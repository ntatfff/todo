# %%
# Root dataset path
rootPath = 'dataset/ngtdm/kernel5-radius5/'

# %%
# Utilities: loaders and validation
import os
import sys
import glob
import csv
from typing import List, Tuple
import numpy as np
import SimpleITK as sitk

def load_array(path: str) -> np.ndarray:
    ext = os.path.splitext(path)[1].lower()
    if ext != '.nrrd':
        raise ValueError(f"Unsupported file type for this notebook (expected .nrrd): {path}")
    image = sitk.ReadImage(path)
    arr = sitk.GetArrayFromImage(image).astype(np.float32)
    if arr.ndim != 3:
        raise ValueError(f"Expected 3D array, got shape {arr.shape} for {path}")
    return arr

def validate_same_shape(arrs: List[np.ndarray]) -> Tuple[int, int, int]:
    shapes = [a.shape for a in arrs]
    if len(set(shapes)) != 1:
        raise ValueError(f"All arrays must have the same shape, got: {shapes}")
    return arrs[0].shape

# %%
# Combine and export to CSV (skip all-zero rows) using pandas
import pandas as pd
import os
from pathlib import Path 

def nrrd2csv(input_files: List[str], output_csv: str):
  arrays = [load_array(p) for p in input_files]
  shape = validate_same_shape(arrays)
  N = len(arrays)

  # Stack as (N, X, Y, Z) then reshape to (voxels, N)
  stacked = np.stack(arrays, axis=0)  # (N, D, H, W)
  vox_mat = stacked.reshape(N, -1).T       # (D*H*W, N)

  # Filter: keep rows where at least one value != 0
  mask = ~(np.all(vox_mat == 0, axis=1))
  filtered = vox_mat[mask]

  # Create DataFrame and write CSV
  # Column names derived from final token before extension in filename
  # Example: original_firstorder_10Percentile.nrrd -> 10Percentile
  base_names = [os.path.splitext(os.path.basename(p))[0] for p in input_files]
  cols = [bn.split('_')[-1] if '_' in bn else bn for bn in base_names]
  df = pd.DataFrame(filtered, columns=cols)

  Path(output_csv).parent.mkdir(parents=True, exist_ok=True)
  df.to_csv(output_csv, index=False)
  print(f"Saved CSV to: {output_csv} with columns: {cols}")

# %%
datasetPath = rootPath + 'tumor'

patientFolders = os.listdir(datasetPath)
patientFolders.sort()
for patientFolder in patientFolders:
  if patientFolder.startswith('BraTS2021_'):
    patientPath = f"{datasetPath}/{patientFolder}"
    featureFiles = list(filter(lambda f: f.endswith('.nrrd'), os.listdir(patientPath)))
    featureFiles.sort()
    featureFiles = [f"{patientPath}/{featureFile}" for featureFile in featureFiles]
    nrrd2csv(featureFiles, patientPath + '/nrrd2csv.csv')
# Out:
# Saved CSV to: dataset/ngtdm/kernel5-radius5/tumor/BraTS2021_00002/nrrd2csv.csv with columns: ['Busyness', 'Coarseness', 'Complexity', 'Contrast', 'Strength']
# Saved CSV to: dataset/ngtdm/kernel5-radius5/tumor/BraTS2021_00003/nrrd2csv.csv with columns: ['Busyness', 'Coarseness', 'Complexity', 'Contrast', 'Strength']
# Saved CSV to: dataset/ngtdm/kernel5-radius5/tumor/BraTS2021_00005/nrrd2csv.csv with columns: ['Busyness', 'Coarseness', 'Complexity', 'Contrast', 'Strength']
# Saved CSV to: dataset/ngtdm/kernel5-radius5/tumor/BraTS2021_00006/nrrd2csv.csv with columns: ['Busyness', 'Coarseness', 'Complexity', 'Contrast', 'Strength']
# Saved CSV to: dataset/ngtdm/kernel5-radius5/tumor/BraTS2021_00008/nrrd2csv.csv with columns: ['Busyness', 'Coarseness', 'Complexity', 'Contrast', 'Strength']
# Saved CSV to: dataset/ngtdm/kernel5-radius5/tumor/BraTS2021_00009/nrrd2csv.csv with columns: ['Busyness', 'Coarseness', 'Complexity', 'Contrast', 'Strength']
# Saved CSV to: dataset/ngtdm/kernel5-radius5/tumor/BraTS2021_00011/nrrd2csv.csv with columns: ['Busyness', 'Coarseness', 'Complexity', 'Contrast', 'Strength']
# Saved CSV to: dataset/ngtdm/kernel5-radius5/tumor/BraTS2021_00012/nrrd2csv.csv with columns: ['Busyness', 'Coarseness', 'Complexity', 'Contrast', 'Strength']
# Saved CSV to: dataset/ngtdm/kernel5-radius5/tumor/BraTS2021_00014/nrrd2csv.csv with columns: ['Busyness', 'Coarseness', 'Complexity', 'Contrast', 'Strength']
# Saved CSV to: dataset/ngtdm/kernel5-radius5/tumor/BraTS2021_00016/nrrd2csv.csv with columns: ['Busyness', 'Coarseness', 'Complexity', 'Contrast', 'Strength']
# Saved CSV to: dataset/ngtdm/kernel5-radius5/tumor/BraTS2021_00017/nrrd2csv.csv with columns: ['Busyness', 'Coarseness', 'Complexity', 'Contrast', 'Strength']
# Saved CSV to: dataset/ngtdm/kernel5-radius5/tumor/BraTS2021_00018/nrrd2csv.csv with columns: ['Busyness', 'Coarseness', 'Complexity', 'Contrast', 'Strength']
# Saved CSV to: dataset/ngtdm/kernel5-radius5/tumor/BraTS2021_00019/nrrd2csv.csv with columns: ['Busyness', 'Coarseness', 'Complexity', 'Contrast', 'Strength']
# Saved CSV to: dataset/ngtdm/kernel5-radius5/tumor/BraTS2021_00020/nrrd2csv.csv with columns: ['Busyness', 'Coarseness', 'Complexity', 'Contrast', 'Strength']
# Saved CSV to: dataset/ngtdm/kernel5-radius5/tumor/BraTS2021_00021/nrrd2csv.csv with columns: ['Busyness', 'Coarseness', 'Complexity', 'Contrast', 'Strength']
# Saved CSV to: dataset/ngtdm/kernel5-radius5/tumor/BraTS2021_00022/nrrd2csv.csv with columns: ['Busyness', 'Coarseness', 'Complexity', 'Contrast', 'Strength']
# Saved CSV to: dataset/ngtdm/kernel5-radius5/tumor/BraTS2021_00024/nrrd2csv.csv with columns: ['Busyness', 'Coarseness', 'Complexity', 'Contrast', 'Strength']
# Saved CSV to: dataset/ngtdm/kernel5-radius5/tumor/BraTS2021_00025/nrrd2csv.csv with columns: ['Busyness', 'Coarseness', 'Complexity', 'Contrast', 'Strength']
# Saved CSV to: dataset/ngtdm/kernel5-radius5/tumor/BraTS2021_00026/nrrd2csv.csv with columns: ['Busyness', 'Coarseness', 'Complexity', 'Contrast', 'Strength']
# Saved CSV to: dataset/ngtdm/kernel5-radius5/tumor/BraTS2021_00028/nrrd2csv.csv with columns: ['Busyness', 'Coarseness', 'Complexity', 'Contrast', 'Strength']
# Saved CSV to: dataset/ngtdm/kernel5-radius5/tumor/BraTS2021_00030/nrrd2csv.csv with columns: ['Busyness', 'Coarseness', 'Complexity', 'Contrast', 'Strength']
# Saved CSV to: dataset/ngtdm/kernel5-radius5/tumor/BraTS2021_00031/nrrd2csv.csv with columns: ['Busyness', 'Coarseness', 'Complexity', 'Contrast', 'Strength']
# Saved CSV to: dataset/ngtdm/kernel5-radius5/tumor/BraTS2021_00032/nrrd2csv.csv with columns: ['Busyness', 'Coarseness', 'Complexity', 'Contrast', 'Strength']
# Saved CSV to: dataset/ngtdm/kernel5-radius5/tumor/BraTS2021_00033/nrrd2csv.csv with columns: ['Busyness', 'Coarseness', 'Complexity', 'Contrast', 'Strength']
# Saved CSV to: dataset/ngtdm/kernel5-radius5/tumor/BraTS2021_00035/nrrd2csv.csv with columns: ['Busyness', 'Coarseness', 'Complexity', 'Contrast', 'Strength']
# Saved CSV to: dataset/ngtdm/kernel5-radius5/tumor/BraTS2021_00036/nrrd2csv.csv with columns: ['Busyness', 'Coarseness', 'Complexity', 'Contrast', 'Strength']
# Saved CSV to: dataset/ngtdm/kernel5-radius5/tumor/BraTS2021_00043/nrrd2csv.csv with columns: ['Busyness', 'Coarseness', 'Complexity', 'Contrast', 'Strength']
# Saved CSV to: dataset/ngtdm/kernel5-radius5/tumor/BraTS2021_00044/nrrd2csv.csv with columns: ['Busyness', 'Coarseness', 'Complexity', 'Contrast', 'Strength']
# Saved CSV to: dataset/ngtdm/kernel5-radius5/tumor/BraTS2021_00045/nrrd2csv.csv with columns: ['Busyness', 'Coarseness', 'Complexity', 'Contrast', 'Strength']
# Saved CSV to: dataset/ngtdm/kernel5-radius5/tumor/BraTS2021_00046/nrrd2csv.csv with columns: ['Busyness', 'Coarseness', 'Complexity', 'Contrast', 'Strength']
# Saved CSV to: dataset/ngtdm/kernel5-radius5/tumor/BraTS2021_00048/nrrd2csv.csv with columns: ['Busyness', 'Coarseness', 'Complexity', 'Contrast', 'Strength']
# Saved CSV to: dataset/ngtdm/kernel5-radius5/tumor/BraTS2021_00049/nrrd2csv.csv with columns: ['Busyness', 'Coarseness', 'Complexity', 'Contrast', 'Strength']
# Saved CSV to: dataset/ngtdm/kernel5-radius5/tumor/BraTS2021_00051/nrrd2csv.csv with columns: ['Busyness', 'Coarseness', 'Complexity', 'Contrast', 'Strength']
# Saved CSV to: dataset/ngtdm/kernel5-radius5/tumor/BraTS2021_00052/nrrd2csv.csv with columns: ['Busyness', 'Coarseness', 'Complexity', 'Contrast', 'Strength']
# Saved CSV to: dataset/ngtdm/kernel5-radius5/tumor/BraTS2021_00053/nrrd2csv.csv with columns: ['Busyness', 'Coarseness', 'Complexity', 'Contrast', 'Strength']
# Saved CSV to: dataset/ngtdm/kernel5-radius5/tumor/BraTS2021_00054/nrrd2csv.csv with columns: ['Busyness', 'Coarseness', 'Complexity', 'Contrast', 'Strength']
# Saved CSV to: dataset/ngtdm/kernel5-radius5/tumor/BraTS2021_00056/nrrd2csv.csv with columns: ['Busyness', 'Coarseness', 'Complexity', 'Contrast', 'Strength']
# Saved CSV to: dataset/ngtdm/kernel5-radius5/tumor/BraTS2021_00058/nrrd2csv.csv with columns: ['Busyness', 'Coarseness', 'Complexity', 'Contrast', 'Strength']
# Saved CSV to: dataset/ngtdm/kernel5-radius5/tumor/BraTS2021_00059/nrrd2csv.csv with columns: ['Busyness', 'Coarseness', 'Complexity', 'Contrast', 'Strength']
# Saved CSV to: dataset/ngtdm/kernel5-radius5/tumor/BraTS2021_00060/nrrd2csv.csv with columns: ['Busyness', 'Coarseness', 'Complexity', 'Contrast', 'Strength']
# Saved CSV to: dataset/ngtdm/kernel5-radius5/tumor/BraTS2021_00061/nrrd2csv.csv with columns: ['Busyness', 'Coarseness', 'Complexity', 'Contrast', 'Strength']
# Saved CSV to: dataset/ngtdm/kernel5-radius5/tumor/BraTS2021_00062/nrrd2csv.csv with columns: ['Busyness', 'Coarseness', 'Complexity', 'Contrast', 'Strength']
# Saved CSV to: dataset/ngtdm/kernel5-radius5/tumor/BraTS2021_00063/nrrd2csv.csv with columns: ['Busyness', 'Coarseness', 'Complexity', 'Contrast', 'Strength']
# Saved CSV to: dataset/ngtdm/kernel5-radius5/tumor/BraTS2021_00064/nrrd2csv.csv with columns: ['Busyness', 'Coarseness', 'Complexity', 'Contrast', 'Strength']
# Saved CSV to: dataset/ngtdm/kernel5-radius5/tumor/BraTS2021_00066/nrrd2csv.csv with columns: ['Busyness', 'Coarseness', 'Complexity', 'Contrast', 'Strength']
# Saved CSV to: dataset/ngtdm/kernel5-radius5/tumor/BraTS2021_00068/nrrd2csv.csv with columns: ['Busyness', 'Coarseness', 'Complexity', 'Contrast', 'Strength']
# Saved CSV to: dataset/ngtdm/kernel5-radius5/tumor/BraTS2021_00070/nrrd2csv.csv with columns: ['Busyness', 'Coarseness', 'Complexity', 'Contrast', 'Strength']
# Saved CSV to: dataset/ngtdm/kernel5-radius5/tumor/BraTS2021_00071/nrrd2csv.csv with columns: ['Busyness', 'Coarseness', 'Complexity', 'Contrast', 'Strength']
# Saved CSV to: dataset/ngtdm/kernel5-radius5/tumor/BraTS2021_00072/nrrd2csv.csv with columns: ['Busyness', 'Coarseness', 'Complexity', 'Contrast', 'Strength']
# Saved CSV to: dataset/ngtdm/kernel5-radius5/tumor/BraTS2021_00074/nrrd2csv.csv with columns: ['Busyness', 'Coarseness', 'Complexity', 'Contrast', 'Strength']
# Saved CSV to: dataset/ngtdm/kernel5-radius5/tumor/BraTS2021_00077/nrrd2csv.csv with columns: ['Busyness', 'Coarseness', 'Complexity', 'Contrast', 'Strength']
# Saved CSV to: dataset/ngtdm/kernel5-radius5/tumor/BraTS2021_00078/nrrd2csv.csv with columns: ['Busyness', 'Coarseness', 'Complexity', 'Contrast', 'Strength']
# Saved CSV to: dataset/ngtdm/kernel5-radius5/tumor/BraTS2021_00081/nrrd2csv.csv with columns: ['Busyness', 'Coarseness', 'Complexity', 'Contrast', 'Strength']
# Saved CSV to: dataset/ngtdm/kernel5-radius5/tumor/BraTS2021_00084/nrrd2csv.csv with columns: ['Busyness', 'Coarseness', 'Complexity', 'Contrast', 'Strength']
# Saved CSV to: dataset/ngtdm/kernel5-radius5/tumor/BraTS2021_00085/nrrd2csv.csv with columns: ['Busyness', 'Coarseness', 'Complexity', 'Contrast', 'Strength']
# Saved CSV to: dataset/ngtdm/kernel5-radius5/tumor/BraTS2021_00087/nrrd2csv.csv with columns: ['Busyness', 'Coarseness', 'Complexity', 'Contrast', 'Strength']
# Saved CSV to: dataset/ngtdm/kernel5-radius5/tumor/BraTS2021_00088/nrrd2csv.csv with columns: ['Busyness', 'Coarseness', 'Complexity', 'Contrast', 'Strength']
# Saved CSV to: dataset/ngtdm/kernel5-radius5/tumor/BraTS2021_00089/nrrd2csv.csv with columns: ['Busyness', 'Coarseness', 'Complexity', 'Contrast', 'Strength']
# Saved CSV to: dataset/ngtdm/kernel5-radius5/tumor/BraTS2021_00090/nrrd2csv.csv with columns: ['Busyness', 'Coarseness', 'Complexity', 'Contrast', 'Strength']
# Saved CSV to: dataset/ngtdm/kernel5-radius5/tumor/BraTS2021_00094/nrrd2csv.csv with columns: ['Busyness', 'Coarseness', 'Complexity', 'Contrast', 'Strength']
# Saved CSV to: dataset/ngtdm/kernel5-radius5/tumor/BraTS2021_00095/nrrd2csv.csv with columns: ['Busyness', 'Coarseness', 'Complexity', 'Contrast', 'Strength']
# Saved CSV to: dataset/ngtdm/kernel5-radius5/tumor/BraTS2021_00096/nrrd2csv.csv with columns: ['Busyness', 'Coarseness', 'Complexity', 'Contrast', 'Strength']
# Saved CSV to: dataset/ngtdm/kernel5-radius5/tumor/BraTS2021_00097/nrrd2csv.csv with columns: ['Busyness', 'Coarseness', 'Complexity', 'Contrast', 'Strength']
# Saved CSV to: dataset/ngtdm/kernel5-radius5/tumor/BraTS2021_00098/nrrd2csv.csv with columns: ['Busyness', 'Coarseness', 'Complexity', 'Contrast', 'Strength']
# Saved CSV to: dataset/ngtdm/kernel5-radius5/tumor/BraTS2021_00099/nrrd2csv.csv with columns: ['Busyness', 'Coarseness', 'Complexity', 'Contrast', 'Strength']
# Saved CSV to: dataset/ngtdm/kernel5-radius5/tumor/BraTS2021_00100/nrrd2csv.csv with columns: ['Busyness', 'Coarseness', 'Complexity', 'Contrast', 'Strength']
# Saved CSV to: dataset/ngtdm/kernel5-radius5/tumor/BraTS2021_00101/nrrd2csv.csv with columns: ['Busyness', 'Coarseness', 'Complexity', 'Contrast', 'Strength']
# Saved CSV to: dataset/ngtdm/kernel5-radius5/tumor/BraTS2021_00102/nrrd2csv.csv with columns: ['Busyness', 'Coarseness', 'Complexity', 'Contrast', 'Strength']
# Saved CSV to: dataset/ngtdm/kernel5-radius5/tumor/BraTS2021_00103/nrrd2csv.csv with columns: ['Busyness', 'Coarseness', 'Complexity', 'Contrast', 'Strength']
# Saved CSV to: dataset/ngtdm/kernel5-radius5/tumor/BraTS2021_00104/nrrd2csv.csv with columns: ['Busyness', 'Coarseness', 'Complexity', 'Contrast', 'Strength']
# Saved CSV to: dataset/ngtdm/kernel5-radius5/tumor/BraTS2021_00105/nrrd2csv.csv with columns: ['Busyness', 'Coarseness', 'Complexity', 'Contrast', 'Strength']
# Saved CSV to: dataset/ngtdm/kernel5-radius5/tumor/BraTS2021_00106/nrrd2csv.csv with columns: ['Busyness', 'Coarseness', 'Complexity', 'Contrast', 'Strength']
# Saved CSV to: dataset/ngtdm/kernel5-radius5/tumor/BraTS2021_00107/nrrd2csv.csv with columns: ['Busyness', 'Coarseness', 'Complexity', 'Contrast', 'Strength']
# Saved CSV to: dataset/ngtdm/kernel5-radius5/tumor/BraTS2021_00108/nrrd2csv.csv with columns: ['Busyness', 'Coarseness', 'Complexity', 'Contrast', 'Strength']
# Saved CSV to: dataset/ngtdm/kernel5-radius5/tumor/BraTS2021_00109/nrrd2csv.csv with columns: ['Busyness', 'Coarseness', 'Complexity', 'Contrast', 'Strength']
# Saved CSV to: dataset/ngtdm/kernel5-radius5/tumor/BraTS2021_00110/nrrd2csv.csv with columns: ['Busyness', 'Coarseness', 'Complexity', 'Contrast', 'Strength']
# Saved CSV to: dataset/ngtdm/kernel5-radius5/tumor/BraTS2021_00111/nrrd2csv.csv with columns: ['Busyness', 'Coarseness', 'Complexity', 'Contrast', 'Strength']
# Saved CSV to: dataset/ngtdm/kernel5-radius5/tumor/BraTS2021_00112/nrrd2csv.csv with columns: ['Busyness', 'Coarseness', 'Complexity', 'Contrast', 'Strength']
# Saved CSV to: dataset/ngtdm/kernel5-radius5/tumor/BraTS2021_00113/nrrd2csv.csv with columns: ['Busyness', 'Coarseness', 'Complexity', 'Contrast', 'Strength']
# Saved CSV to: dataset/ngtdm/kernel5-radius5/tumor/BraTS2021_00115/nrrd2csv.csv with columns: ['Busyness', 'Coarseness', 'Complexity', 'Contrast', 'Strength']
# Saved CSV to: dataset/ngtdm/kernel5-radius5/tumor/BraTS2021_00116/nrrd2csv.csv with columns: ['Busyness', 'Coarseness', 'Complexity', 'Contrast', 'Strength']
# Saved CSV to: dataset/ngtdm/kernel5-radius5/tumor/BraTS2021_00117/nrrd2csv.csv with columns: ['Busyness', 'Coarseness', 'Complexity', 'Contrast', 'Strength']
# Saved CSV to: dataset/ngtdm/kernel5-radius5/tumor/BraTS2021_00118/nrrd2csv.csv with columns: ['Busyness', 'Coarseness', 'Complexity', 'Contrast', 'Strength']
# Saved CSV to: dataset/ngtdm/kernel5-radius5/tumor/BraTS2021_00120/nrrd2csv.csv with columns: ['Busyness', 'Coarseness', 'Complexity', 'Contrast', 'Strength']
# Saved CSV to: dataset/ngtdm/kernel5-radius5/tumor/BraTS2021_00121/nrrd2csv.csv with columns: ['Busyness', 'Coarseness', 'Complexity', 'Contrast', 'Strength']
# Saved CSV to: dataset/ngtdm/kernel5-radius5/tumor/BraTS2021_00122/nrrd2csv.csv with columns: ['Busyness', 'Coarseness', 'Complexity', 'Contrast', 'Strength']
# Saved CSV to: dataset/ngtdm/kernel5-radius5/tumor/BraTS2021_00123/nrrd2csv.csv with columns: ['Busyness', 'Coarseness', 'Complexity', 'Contrast', 'Strength']
# Saved CSV to: dataset/ngtdm/kernel5-radius5/tumor/BraTS2021_00124/nrrd2csv.csv with columns: ['Busyness', 'Coarseness', 'Complexity', 'Contrast', 'Strength']
# Saved CSV to: dataset/ngtdm/kernel5-radius5/tumor/BraTS2021_00126/nrrd2csv.csv with columns: ['Busyness', 'Coarseness', 'Complexity', 'Contrast', 'Strength']
# Saved CSV to: dataset/ngtdm/kernel5-radius5/tumor/BraTS2021_00127/nrrd2csv.csv with columns: ['Busyness', 'Coarseness', 'Complexity', 'Contrast', 'Strength']
# Saved CSV to: dataset/ngtdm/kernel5-radius5/tumor/BraTS2021_00128/nrrd2csv.csv with columns: ['Busyness', 'Coarseness', 'Complexity', 'Contrast', 'Strength']
# Saved CSV to: dataset/ngtdm/kernel5-radius5/tumor/BraTS2021_00130/nrrd2csv.csv with columns: ['Busyness', 'Coarseness', 'Complexity', 'Contrast', 'Strength']
# Saved CSV to: dataset/ngtdm/kernel5-radius5/tumor/BraTS2021_00131/nrrd2csv.csv with columns: ['Busyness', 'Coarseness', 'Complexity', 'Contrast', 'Strength']
# Saved CSV to: dataset/ngtdm/kernel5-radius5/tumor/BraTS2021_00132/nrrd2csv.csv with columns: ['Busyness', 'Coarseness', 'Complexity', 'Contrast', 'Strength']
# Saved CSV to: dataset/ngtdm/kernel5-radius5/tumor/BraTS2021_00133/nrrd2csv.csv with columns: ['Busyness', 'Coarseness', 'Complexity', 'Contrast', 'Strength']
# Saved CSV to: dataset/ngtdm/kernel5-radius5/tumor/BraTS2021_00134/nrrd2csv.csv with columns: ['Busyness', 'Coarseness', 'Complexity', 'Contrast', 'Strength']
# Saved CSV to: dataset/ngtdm/kernel5-radius5/tumor/BraTS2021_00136/nrrd2csv.csv with columns: ['Busyness', 'Coarseness', 'Complexity', 'Contrast', 'Strength']
# Saved CSV to: dataset/ngtdm/kernel5-radius5/tumor/BraTS2021_00137/nrrd2csv.csv with columns: ['Busyness', 'Coarseness', 'Complexity', 'Contrast', 'Strength']
# Saved CSV to: dataset/ngtdm/kernel5-radius5/tumor/BraTS2021_00138/nrrd2csv.csv with columns: ['Busyness', 'Coarseness', 'Complexity', 'Contrast', 'Strength']
# Saved CSV to: dataset/ngtdm/kernel5-radius5/tumor/BraTS2021_00139/nrrd2csv.csv with columns: ['Busyness', 'Coarseness', 'Complexity', 'Contrast', 'Strength']
# Saved CSV to: dataset/ngtdm/kernel5-radius5/tumor/BraTS2021_00140/nrrd2csv.csv with columns: ['Busyness', 'Coarseness', 'Complexity', 'Contrast', 'Strength']
# Saved CSV to: dataset/ngtdm/kernel5-radius5/tumor/BraTS2021_00142/nrrd2csv.csv with columns: ['Busyness', 'Coarseness', 'Complexity', 'Contrast', 'Strength']
# Saved CSV to: dataset/ngtdm/kernel5-radius5/tumor/BraTS2021_00143/nrrd2csv.csv with columns: ['Busyness', 'Coarseness', 'Complexity', 'Contrast', 'Strength']
# Saved CSV to: dataset/ngtdm/kernel5-radius5/tumor/BraTS2021_00144/nrrd2csv.csv with columns: ['Busyness', 'Coarseness', 'Complexity', 'Contrast', 'Strength']
# Saved CSV to: dataset/ngtdm/kernel5-radius5/tumor/BraTS2021_00146/nrrd2csv.csv with columns: ['Busyness', 'Coarseness', 'Complexity', 'Contrast', 'Strength']
# Saved CSV to: dataset/ngtdm/kernel5-radius5/tumor/BraTS2021_00147/nrrd2csv.csv with columns: ['Busyness', 'Coarseness', 'Complexity', 'Contrast', 'Strength']
# Saved CSV to: dataset/ngtdm/kernel5-radius5/tumor/BraTS2021_00148/nrrd2csv.csv with columns: ['Busyness', 'Coarseness', 'Complexity', 'Contrast', 'Strength']
# Saved CSV to: dataset/ngtdm/kernel5-radius5/tumor/BraTS2021_00149/nrrd2csv.csv with columns: ['Busyness', 'Coarseness', 'Complexity', 'Contrast', 'Strength']
# Saved CSV to: dataset/ngtdm/kernel5-radius5/tumor/BraTS2021_00150/nrrd2csv.csv with columns: ['Busyness', 'Coarseness', 'Complexity', 'Contrast', 'Strength']
# Saved CSV to: dataset/ngtdm/kernel5-radius5/tumor/BraTS2021_00151/nrrd2csv.csv with columns: ['Busyness', 'Coarseness', 'Complexity', 'Contrast', 'Strength']
# Saved CSV to: dataset/ngtdm/kernel5-radius5/tumor/BraTS2021_00152/nrrd2csv.csv with columns: ['Busyness', 'Coarseness', 'Complexity', 'Contrast', 'Strength']
# Saved CSV to: dataset/ngtdm/kernel5-radius5/tumor/BraTS2021_00154/nrrd2csv.csv with columns: ['Busyness', 'Coarseness', 'Complexity', 'Contrast', 'Strength']
# Saved CSV to: dataset/ngtdm/kernel5-radius5/tumor/BraTS2021_00155/nrrd2csv.csv with columns: ['Busyness', 'Coarseness', 'Complexity', 'Contrast', 'Strength']
# Saved CSV to: dataset/ngtdm/kernel5-radius5/tumor/BraTS2021_00156/nrrd2csv.csv with columns: ['Busyness', 'Coarseness', 'Complexity', 'Contrast', 'Strength']
# Saved CSV to: dataset/ngtdm/kernel5-radius5/tumor/BraTS2021_00157/nrrd2csv.csv with columns: ['Busyness', 'Coarseness', 'Complexity', 'Contrast', 'Strength']
# Saved CSV to: dataset/ngtdm/kernel5-radius5/tumor/BraTS2021_00158/nrrd2csv.csv with columns: ['Busyness', 'Coarseness', 'Complexity', 'Contrast', 'Strength']
# Saved CSV to: dataset/ngtdm/kernel5-radius5/tumor/BraTS2021_00159/nrrd2csv.csv with columns: ['Busyness', 'Coarseness', 'Complexity', 'Contrast', 'Strength']
# Saved CSV to: dataset/ngtdm/kernel5-radius5/tumor/BraTS2021_00160/nrrd2csv.csv with columns: ['Busyness', 'Coarseness', 'Complexity', 'Contrast', 'Strength']
# Saved CSV to: dataset/ngtdm/kernel5-radius5/tumor/BraTS2021_00162/nrrd2csv.csv with columns: ['Busyness', 'Coarseness', 'Complexity', 'Contrast', 'Strength']
# Saved CSV to: dataset/ngtdm/kernel5-radius5/tumor/BraTS2021_00165/nrrd2csv.csv with columns: ['Busyness', 'Coarseness', 'Complexity', 'Contrast', 'Strength']
# Saved CSV to: dataset/ngtdm/kernel5-radius5/tumor/BraTS2021_00166/nrrd2csv.csv with columns: ['Busyness', 'Coarseness', 'Complexity', 'Contrast', 'Strength']
# Saved CSV to: dataset/ngtdm/kernel5-radius5/tumor/BraTS2021_00167/nrrd2csv.csv with columns: ['Busyness', 'Coarseness', 'Complexity', 'Contrast', 'Strength']
# Saved CSV to: dataset/ngtdm/kernel5-radius5/tumor/BraTS2021_00170/nrrd2csv.csv with columns: ['Busyness', 'Coarseness', 'Complexity', 'Contrast', 'Strength']
# Saved CSV to: dataset/ngtdm/kernel5-radius5/tumor/BraTS2021_00171/nrrd2csv.csv with columns: ['Busyness', 'Coarseness', 'Complexity', 'Contrast', 'Strength']
# Saved CSV to: dataset/ngtdm/kernel5-radius5/tumor/BraTS2021_00172/nrrd2csv.csv with columns: ['Busyness', 'Coarseness', 'Complexity', 'Contrast', 'Strength']
# Saved CSV to: dataset/ngtdm/kernel5-radius5/tumor/BraTS2021_00176/nrrd2csv.csv with columns: ['Busyness', 'Coarseness', 'Complexity', 'Contrast', 'Strength']
# Saved CSV to: dataset/ngtdm/kernel5-radius5/tumor/BraTS2021_00177/nrrd2csv.csv with columns: ['Busyness', 'Coarseness', 'Complexity', 'Contrast', 'Strength']
# Saved CSV to: dataset/ngtdm/kernel5-radius5/tumor/BraTS2021_00178/nrrd2csv.csv with columns: ['Busyness', 'Coarseness', 'Complexity', 'Contrast', 'Strength']
# Saved CSV to: dataset/ngtdm/kernel5-radius5/tumor/BraTS2021_00183/nrrd2csv.csv with columns: ['Busyness', 'Coarseness', 'Complexity', 'Contrast', 'Strength']
# Saved CSV to: dataset/ngtdm/kernel5-radius5/tumor/BraTS2021_00184/nrrd2csv.csv with columns: ['Busyness', 'Coarseness', 'Complexity', 'Contrast', 'Strength']
# Saved CSV to: dataset/ngtdm/kernel5-radius5/tumor/BraTS2021_00185/nrrd2csv.csv with columns: ['Busyness', 'Coarseness', 'Complexity', 'Contrast', 'Strength']
# Saved CSV to: dataset/ngtdm/kernel5-radius5/tumor/BraTS2021_00186/nrrd2csv.csv with columns: ['Busyness', 'Coarseness', 'Complexity', 'Contrast', 'Strength']
# Saved CSV to: dataset/ngtdm/kernel5-radius5/tumor/BraTS2021_00187/nrrd2csv.csv with columns: ['Busyness', 'Coarseness', 'Complexity', 'Contrast', 'Strength']
# Saved CSV to: dataset/ngtdm/kernel5-radius5/tumor/BraTS2021_00188/nrrd2csv.csv with columns: ['Busyness', 'Coarseness', 'Complexity', 'Contrast', 'Strength']
# Saved CSV to: dataset/ngtdm/kernel5-radius5/tumor/BraTS2021_00191/nrrd2csv.csv with columns: ['Busyness', 'Coarseness', 'Complexity', 'Contrast', 'Strength']
# Saved CSV to: dataset/ngtdm/kernel5-radius5/tumor/BraTS2021_00192/nrrd2csv.csv with columns: ['Busyness', 'Coarseness', 'Complexity', 'Contrast', 'Strength']
# Saved CSV to: dataset/ngtdm/kernel5-radius5/tumor/BraTS2021_00193/nrrd2csv.csv with columns: ['Busyness', 'Coarseness', 'Complexity', 'Contrast', 'Strength']
# Saved CSV to: dataset/ngtdm/kernel5-radius5/tumor/BraTS2021_00194/nrrd2csv.csv with columns: ['Busyness', 'Coarseness', 'Complexity', 'Contrast', 'Strength']
# Saved CSV to: dataset/ngtdm/kernel5-radius5/tumor/BraTS2021_00195/nrrd2csv.csv with columns: ['Busyness', 'Coarseness', 'Complexity', 'Contrast', 'Strength']
# Saved CSV to: dataset/ngtdm/kernel5-radius5/tumor/BraTS2021_00196/nrrd2csv.csv with columns: ['Busyness', 'Coarseness', 'Complexity', 'Contrast', 'Strength']
# Saved CSV to: dataset/ngtdm/kernel5-radius5/tumor/BraTS2021_00199/nrrd2csv.csv with columns: ['Busyness', 'Coarseness', 'Complexity', 'Contrast', 'Strength']
# Saved CSV to: dataset/ngtdm/kernel5-radius5/tumor/BraTS2021_00201/nrrd2csv.csv with columns: ['Busyness', 'Coarseness', 'Complexity', 'Contrast', 'Strength']
# Saved CSV to: dataset/ngtdm/kernel5-radius5/tumor/BraTS2021_00203/nrrd2csv.csv with columns: ['Busyness', 'Coarseness', 'Complexity', 'Contrast', 'Strength']
# Saved CSV to: dataset/ngtdm/kernel5-radius5/tumor/BraTS2021_00204/nrrd2csv.csv with columns: ['Busyness', 'Coarseness', 'Complexity', 'Contrast', 'Strength']
# Saved CSV to: dataset/ngtdm/kernel5-radius5/tumor/BraTS2021_00206/nrrd2csv.csv with columns: ['Busyness', 'Coarseness', 'Complexity', 'Contrast', 'Strength']
# Saved CSV to: dataset/ngtdm/kernel5-radius5/tumor/BraTS2021_00207/nrrd2csv.csv with columns: ['Busyness', 'Coarseness', 'Complexity', 'Contrast', 'Strength']
# Saved CSV to: dataset/ngtdm/kernel5-radius5/tumor/BraTS2021_00209/nrrd2csv.csv with columns: ['Busyness', 'Coarseness', 'Complexity', 'Contrast', 'Strength']
# Saved CSV to: dataset/ngtdm/kernel5-radius5/tumor/BraTS2021_00210/nrrd2csv.csv with columns: ['Busyness', 'Coarseness', 'Complexity', 'Contrast', 'Strength']
# Saved CSV to: dataset/ngtdm/kernel5-radius5/tumor/BraTS2021_00211/nrrd2csv.csv with columns: ['Busyness', 'Coarseness', 'Complexity', 'Contrast', 'Strength']
# Saved CSV to: dataset/ngtdm/kernel5-radius5/tumor/BraTS2021_00212/nrrd2csv.csv with columns: ['Busyness', 'Coarseness', 'Complexity', 'Contrast', 'Strength']
# Saved CSV to: dataset/ngtdm/kernel5-radius5/tumor/BraTS2021_00214/nrrd2csv.csv with columns: ['Busyness', 'Coarseness', 'Complexity', 'Contrast', 'Strength']
# Saved CSV to: dataset/ngtdm/kernel5-radius5/tumor/BraTS2021_00216/nrrd2csv.csv with columns: ['Busyness', 'Coarseness', 'Complexity', 'Contrast', 'Strength']
# Saved CSV to: dataset/ngtdm/kernel5-radius5/tumor/BraTS2021_00217/nrrd2csv.csv with columns: ['Busyness', 'Coarseness', 'Complexity', 'Contrast', 'Strength']
# Saved CSV to: dataset/ngtdm/kernel5-radius5/tumor/BraTS2021_00218/nrrd2csv.csv with columns: ['Busyness', 'Coarseness', 'Complexity', 'Contrast', 'Strength']
# Saved CSV to: dataset/ngtdm/kernel5-radius5/tumor/BraTS2021_00219/nrrd2csv.csv with columns: ['Busyness', 'Coarseness', 'Complexity', 'Contrast', 'Strength']
# Saved CSV to: dataset/ngtdm/kernel5-radius5/tumor/BraTS2021_00220/nrrd2csv.csv with columns: ['Busyness', 'Coarseness', 'Complexity', 'Contrast', 'Strength']
# Saved CSV to: dataset/ngtdm/kernel5-radius5/tumor/BraTS2021_00221/nrrd2csv.csv with columns: ['Busyness', 'Coarseness', 'Complexity', 'Contrast', 'Strength']
# Saved CSV to: dataset/ngtdm/kernel5-radius5/tumor/BraTS2021_00222/nrrd2csv.csv with columns: ['Busyness', 'Coarseness', 'Complexity', 'Contrast', 'Strength']
# Saved CSV to: dataset/ngtdm/kernel5-radius5/tumor/BraTS2021_00227/nrrd2csv.csv with columns: ['Busyness', 'Coarseness', 'Complexity', 'Contrast', 'Strength']
# Saved CSV to: dataset/ngtdm/kernel5-radius5/tumor/BraTS2021_00228/nrrd2csv.csv with columns: ['Busyness', 'Coarseness', 'Complexity', 'Contrast', 'Strength']
# Saved CSV to: dataset/ngtdm/kernel5-radius5/tumor/BraTS2021_00230/nrrd2csv.csv with columns: ['Busyness', 'Coarseness', 'Complexity', 'Contrast', 'Strength']
# Saved CSV to: dataset/ngtdm/kernel5-radius5/tumor/BraTS2021_00231/nrrd2csv.csv with columns: ['Busyness', 'Coarseness', 'Complexity', 'Contrast', 'Strength']
# Saved CSV to: dataset/ngtdm/kernel5-radius5/tumor/BraTS2021_00233/nrrd2csv.csv with columns: ['Busyness', 'Coarseness', 'Complexity', 'Contrast', 'Strength']
# Saved CSV to: dataset/ngtdm/kernel5-radius5/tumor/BraTS2021_00234/nrrd2csv.csv with columns: ['Busyness', 'Coarseness', 'Complexity', 'Contrast', 'Strength']
# Saved CSV to: dataset/ngtdm/kernel5-radius5/tumor/BraTS2021_00235/nrrd2csv.csv with columns: ['Busyness', 'Coarseness', 'Complexity', 'Contrast', 'Strength']
# Saved CSV to: dataset/ngtdm/kernel5-radius5/tumor/BraTS2021_00236/nrrd2csv.csv with columns: ['Busyness', 'Coarseness', 'Complexity', 'Contrast', 'Strength']
# Saved CSV to: dataset/ngtdm/kernel5-radius5/tumor/BraTS2021_00237/nrrd2csv.csv with columns: ['Busyness', 'Coarseness', 'Complexity', 'Contrast', 'Strength']
# Saved CSV to: dataset/ngtdm/kernel5-radius5/tumor/BraTS2021_00238/nrrd2csv.csv with columns: ['Busyness', 'Coarseness', 'Complexity', 'Contrast', 'Strength']
# Saved CSV to: dataset/ngtdm/kernel5-radius5/tumor/BraTS2021_00239/nrrd2csv.csv with columns: ['Busyness', 'Coarseness', 'Complexity', 'Contrast', 'Strength']
# Saved CSV to: dataset/ngtdm/kernel5-radius5/tumor/BraTS2021_00240/nrrd2csv.csv with columns: ['Busyness', 'Coarseness', 'Complexity', 'Contrast', 'Strength']
# Saved CSV to: dataset/ngtdm/kernel5-radius5/tumor/BraTS2021_00241/nrrd2csv.csv with columns: ['Busyness', 'Coarseness', 'Complexity', 'Contrast', 'Strength']
# Saved CSV to: dataset/ngtdm/kernel5-radius5/tumor/BraTS2021_00242/nrrd2csv.csv with columns: ['Busyness', 'Coarseness', 'Complexity', 'Contrast', 'Strength']
# Saved CSV to: dataset/ngtdm/kernel5-radius5/tumor/BraTS2021_00243/nrrd2csv.csv with columns: ['Busyness', 'Coarseness', 'Complexity', 'Contrast', 'Strength']
# Saved CSV to: dataset/ngtdm/kernel5-radius5/tumor/BraTS2021_00246/nrrd2csv.csv with columns: ['Busyness', 'Coarseness', 'Complexity', 'Contrast', 'Strength']
# Saved CSV to: dataset/ngtdm/kernel5-radius5/tumor/BraTS2021_00247/nrrd2csv.csv with columns: ['Busyness', 'Coarseness', 'Complexity', 'Contrast', 'Strength']
# Saved CSV to: dataset/ngtdm/kernel5-radius5/tumor/BraTS2021_00249/nrrd2csv.csv with columns: ['Busyness', 'Coarseness', 'Complexity', 'Contrast', 'Strength']
# Saved CSV to: dataset/ngtdm/kernel5-radius5/tumor/BraTS2021_00250/nrrd2csv.csv with columns: ['Busyness', 'Coarseness', 'Complexity', 'Contrast', 'Strength']
# Saved CSV to: dataset/ngtdm/kernel5-radius5/tumor/BraTS2021_00251/nrrd2csv.csv with columns: ['Busyness', 'Coarseness', 'Complexity', 'Contrast', 'Strength']
# Saved CSV to: dataset/ngtdm/kernel5-radius5/tumor/BraTS2021_00253/nrrd2csv.csv with columns: ['Busyness', 'Coarseness', 'Complexity', 'Contrast', 'Strength']
# Saved CSV to: dataset/ngtdm/kernel5-radius5/tumor/BraTS2021_00254/nrrd2csv.csv with columns: ['Busyness', 'Coarseness', 'Complexity', 'Contrast', 'Strength']
# Saved CSV to: dataset/ngtdm/kernel5-radius5/tumor/BraTS2021_00258/nrrd2csv.csv with columns: ['Busyness', 'Coarseness', 'Complexity', 'Contrast', 'Strength']
# Saved CSV to: dataset/ngtdm/kernel5-radius5/tumor/BraTS2021_00259/nrrd2csv.csv with columns: ['Busyness', 'Coarseness', 'Complexity', 'Contrast', 'Strength']
# Saved CSV to: dataset/ngtdm/kernel5-radius5/tumor/BraTS2021_00260/nrrd2csv.csv with columns: ['Busyness', 'Coarseness', 'Complexity', 'Contrast', 'Strength']
# Saved CSV to: dataset/ngtdm/kernel5-radius5/tumor/BraTS2021_00261/nrrd2csv.csv with columns: ['Busyness', 'Coarseness', 'Complexity', 'Contrast', 'Strength']
# Saved CSV to: dataset/ngtdm/kernel5-radius5/tumor/BraTS2021_00262/nrrd2csv.csv with columns: ['Busyness', 'Coarseness', 'Complexity', 'Contrast', 'Strength']
# Saved CSV to: dataset/ngtdm/kernel5-radius5/tumor/BraTS2021_00263/nrrd2csv.csv with columns: ['Busyness', 'Coarseness', 'Complexity', 'Contrast', 'Strength']
# Saved CSV to: dataset/ngtdm/kernel5-radius5/tumor/BraTS2021_00266/nrrd2csv.csv with columns: ['Busyness', 'Coarseness', 'Complexity', 'Contrast', 'Strength']
# Saved CSV to: dataset/ngtdm/kernel5-radius5/tumor/BraTS2021_00267/nrrd2csv.csv with columns: ['Busyness', 'Coarseness', 'Complexity', 'Contrast', 'Strength']
# Saved CSV to: dataset/ngtdm/kernel5-radius5/tumor/BraTS2021_00269/nrrd2csv.csv with columns: ['Busyness', 'Coarseness', 'Complexity', 'Contrast', 'Strength']
# Saved CSV to: dataset/ngtdm/kernel5-radius5/tumor/BraTS2021_00270/nrrd2csv.csv with columns: ['Busyness', 'Coarseness', 'Complexity', 'Contrast', 'Strength']
# Saved CSV to: dataset/ngtdm/kernel5-radius5/tumor/BraTS2021_00271/nrrd2csv.csv with columns: ['Busyness', 'Coarseness', 'Complexity', 'Contrast', 'Strength']
# Saved CSV to: dataset/ngtdm/kernel5-radius5/tumor/BraTS2021_00273/nrrd2csv.csv with columns: ['Busyness', 'Coarseness', 'Complexity', 'Contrast', 'Strength']
# Saved CSV to: dataset/ngtdm/kernel5-radius5/tumor/BraTS2021_00274/nrrd2csv.csv with columns: ['Busyness', 'Coarseness', 'Complexity', 'Contrast', 'Strength']
# Saved CSV to: dataset/ngtdm/kernel5-radius5/tumor/BraTS2021_00275/nrrd2csv.csv with columns: ['Busyness', 'Coarseness', 'Complexity', 'Contrast', 'Strength']
# Saved CSV to: dataset/ngtdm/kernel5-radius5/tumor/BraTS2021_00280/nrrd2csv.csv with columns: ['Busyness', 'Coarseness', 'Complexity', 'Contrast', 'Strength']
# Saved CSV to: dataset/ngtdm/kernel5-radius5/tumor/BraTS2021_00281/nrrd2csv.csv with columns: ['Busyness', 'Coarseness', 'Complexity', 'Contrast', 'Strength']
# Saved CSV to: dataset/ngtdm/kernel5-radius5/tumor/BraTS2021_00282/nrrd2csv.csv with columns: ['Busyness', 'Coarseness', 'Complexity', 'Contrast', 'Strength']
# Saved CSV to: dataset/ngtdm/kernel5-radius5/tumor/BraTS2021_00283/nrrd2csv.csv with columns: ['Busyness', 'Coarseness', 'Complexity', 'Contrast', 'Strength']
# Saved CSV to: dataset/ngtdm/kernel5-radius5/tumor/BraTS2021_00284/nrrd2csv.csv with columns: ['Busyness', 'Coarseness', 'Complexity', 'Contrast', 'Strength']
# Saved CSV to: dataset/ngtdm/kernel5-radius5/tumor/BraTS2021_00285/nrrd2csv.csv with columns: ['Busyness', 'Coarseness', 'Complexity', 'Contrast', 'Strength']

# %%
datasetPath = rootPath + 'non_tumor'

patientFolders = os.listdir(datasetPath)
patientFolders.sort()
for patientFolder in patientFolders:
  if patientFolder.startswith('BraTS2021_'):
    patientPath = f"{datasetPath}/{patientFolder}"
    featureFiles = list(filter(lambda f: f.endswith('.nrrd'), os.listdir(patientPath)))
    featureFiles.sort()
    featureFiles = [f"{patientPath}/{featureFile}" for featureFile in featureFiles]
    nrrd2csv(featureFiles, patientPath + '/nrrd2csv.csv')
# Out:
# Saved CSV to: dataset/ngtdm/kernel5-radius5/non_tumor/BraTS2021_00002/nrrd2csv.csv with columns: ['Busyness', 'Coarseness', 'Complexity', 'Contrast', 'Strength']
# Saved CSV to: dataset/ngtdm/kernel5-radius5/non_tumor/BraTS2021_00003/nrrd2csv.csv with columns: ['Busyness', 'Coarseness', 'Complexity', 'Contrast', 'Strength']
# Saved CSV to: dataset/ngtdm/kernel5-radius5/non_tumor/BraTS2021_00005/nrrd2csv.csv with columns: ['Busyness', 'Coarseness', 'Complexity', 'Contrast', 'Strength']
# Saved CSV to: dataset/ngtdm/kernel5-radius5/non_tumor/BraTS2021_00006/nrrd2csv.csv with columns: ['Busyness', 'Coarseness', 'Complexity', 'Contrast', 'Strength']
# Saved CSV to: dataset/ngtdm/kernel5-radius5/non_tumor/BraTS2021_00008/nrrd2csv.csv with columns: ['Busyness', 'Coarseness', 'Complexity', 'Contrast', 'Strength']
# Saved CSV to: dataset/ngtdm/kernel5-radius5/non_tumor/BraTS2021_00009/nrrd2csv.csv with columns: ['Busyness', 'Coarseness', 'Complexity', 'Contrast', 'Strength']
# Saved CSV to: dataset/ngtdm/kernel5-radius5/non_tumor/BraTS2021_00011/nrrd2csv.csv with columns: ['Busyness', 'Coarseness', 'Complexity', 'Contrast', 'Strength']
# Saved CSV to: dataset/ngtdm/kernel5-radius5/non_tumor/BraTS2021_00012/nrrd2csv.csv with columns: ['Busyness', 'Coarseness', 'Complexity', 'Contrast', 'Strength']
# Saved CSV to: dataset/ngtdm/kernel5-radius5/non_tumor/BraTS2021_00014/nrrd2csv.csv with columns: ['Busyness', 'Coarseness', 'Complexity', 'Contrast', 'Strength']
# Saved CSV to: dataset/ngtdm/kernel5-radius5/non_tumor/BraTS2021_00016/nrrd2csv.csv with columns: ['Busyness', 'Coarseness', 'Complexity', 'Contrast', 'Strength']
# Saved CSV to: dataset/ngtdm/kernel5-radius5/non_tumor/BraTS2021_00017/nrrd2csv.csv with columns: ['Busyness', 'Coarseness', 'Complexity', 'Contrast', 'Strength']
# Saved CSV to: dataset/ngtdm/kernel5-radius5/non_tumor/BraTS2021_00018/nrrd2csv.csv with columns: ['Busyness', 'Coarseness', 'Complexity', 'Contrast', 'Strength']
# Saved CSV to: dataset/ngtdm/kernel5-radius5/non_tumor/BraTS2021_00019/nrrd2csv.csv with columns: ['Busyness', 'Coarseness', 'Complexity', 'Contrast', 'Strength']
# Saved CSV to: dataset/ngtdm/kernel5-radius5/non_tumor/BraTS2021_00020/nrrd2csv.csv with columns: ['Busyness', 'Coarseness', 'Complexity', 'Contrast', 'Strength']
# Saved CSV to: dataset/ngtdm/kernel5-radius5/non_tumor/BraTS2021_00021/nrrd2csv.csv with columns: ['Busyness', 'Coarseness', 'Complexity', 'Contrast', 'Strength']
# Saved CSV to: dataset/ngtdm/kernel5-radius5/non_tumor/BraTS2021_00022/nrrd2csv.csv with columns: ['Busyness', 'Coarseness', 'Complexity', 'Contrast', 'Strength']
# Saved CSV to: dataset/ngtdm/kernel5-radius5/non_tumor/BraTS2021_00024/nrrd2csv.csv with columns: ['Busyness', 'Coarseness', 'Complexity', 'Contrast', 'Strength']
# Saved CSV to: dataset/ngtdm/kernel5-radius5/non_tumor/BraTS2021_00025/nrrd2csv.csv with columns: ['Busyness', 'Coarseness', 'Complexity', 'Contrast', 'Strength']
# Saved CSV to: dataset/ngtdm/kernel5-radius5/non_tumor/BraTS2021_00026/nrrd2csv.csv with columns: ['Busyness', 'Coarseness', 'Complexity', 'Contrast', 'Strength']
# Saved CSV to: dataset/ngtdm/kernel5-radius5/non_tumor/BraTS2021_00028/nrrd2csv.csv with columns: ['Busyness', 'Coarseness', 'Complexity', 'Contrast', 'Strength']
# Saved CSV to: dataset/ngtdm/kernel5-radius5/non_tumor/BraTS2021_00030/nrrd2csv.csv with columns: ['Busyness', 'Coarseness', 'Complexity', 'Contrast', 'Strength']
# Saved CSV to: dataset/ngtdm/kernel5-radius5/non_tumor/BraTS2021_00031/nrrd2csv.csv with columns: ['Busyness', 'Coarseness', 'Complexity', 'Contrast', 'Strength']
# Saved CSV to: dataset/ngtdm/kernel5-radius5/non_tumor/BraTS2021_00032/nrrd2csv.csv with columns: ['Busyness', 'Coarseness', 'Complexity', 'Contrast', 'Strength']
# Saved CSV to: dataset/ngtdm/kernel5-radius5/non_tumor/BraTS2021_00033/nrrd2csv.csv with columns: ['Busyness', 'Coarseness', 'Complexity', 'Contrast', 'Strength']
# Saved CSV to: dataset/ngtdm/kernel5-radius5/non_tumor/BraTS2021_00035/nrrd2csv.csv with columns: ['Busyness', 'Coarseness', 'Complexity', 'Contrast', 'Strength']
# Saved CSV to: dataset/ngtdm/kernel5-radius5/non_tumor/BraTS2021_00036/nrrd2csv.csv with columns: ['Busyness', 'Coarseness', 'Complexity', 'Contrast', 'Strength']
# Saved CSV to: dataset/ngtdm/kernel5-radius5/non_tumor/BraTS2021_00043/nrrd2csv.csv with columns: ['Busyness', 'Coarseness', 'Complexity', 'Contrast', 'Strength']
# Saved CSV to: dataset/ngtdm/kernel5-radius5/non_tumor/BraTS2021_00044/nrrd2csv.csv with columns: ['Busyness', 'Coarseness', 'Complexity', 'Contrast', 'Strength']
# Saved CSV to: dataset/ngtdm/kernel5-radius5/non_tumor/BraTS2021_00045/nrrd2csv.csv with columns: ['Busyness', 'Coarseness', 'Complexity', 'Contrast', 'Strength']
# Saved CSV to: dataset/ngtdm/kernel5-radius5/non_tumor/BraTS2021_00046/nrrd2csv.csv with columns: ['Busyness', 'Coarseness', 'Complexity', 'Contrast', 'Strength']
# Saved CSV to: dataset/ngtdm/kernel5-radius5/non_tumor/BraTS2021_00048/nrrd2csv.csv with columns: ['Busyness', 'Coarseness', 'Complexity', 'Contrast', 'Strength']
# Saved CSV to: dataset/ngtdm/kernel5-radius5/non_tumor/BraTS2021_00049/nrrd2csv.csv with columns: ['Busyness', 'Coarseness', 'Complexity', 'Contrast', 'Strength']
# Saved CSV to: dataset/ngtdm/kernel5-radius5/non_tumor/BraTS2021_00051/nrrd2csv.csv with columns: ['Busyness', 'Coarseness', 'Complexity', 'Contrast', 'Strength']
# Saved CSV to: dataset/ngtdm/kernel5-radius5/non_tumor/BraTS2021_00052/nrrd2csv.csv with columns: ['Busyness', 'Coarseness', 'Complexity', 'Contrast', 'Strength']
# Saved CSV to: dataset/ngtdm/kernel5-radius5/non_tumor/BraTS2021_00053/nrrd2csv.csv with columns: ['Busyness', 'Coarseness', 'Complexity', 'Contrast', 'Strength']
# Saved CSV to: dataset/ngtdm/kernel5-radius5/non_tumor/BraTS2021_00054/nrrd2csv.csv with columns: ['Busyness', 'Coarseness', 'Complexity', 'Contrast', 'Strength']
# Saved CSV to: dataset/ngtdm/kernel5-radius5/non_tumor/BraTS2021_00056/nrrd2csv.csv with columns: ['Busyness', 'Coarseness', 'Complexity', 'Contrast', 'Strength']
# Saved CSV to: dataset/ngtdm/kernel5-radius5/non_tumor/BraTS2021_00058/nrrd2csv.csv with columns: ['Busyness', 'Coarseness', 'Complexity', 'Contrast', 'Strength']
# Saved CSV to: dataset/ngtdm/kernel5-radius5/non_tumor/BraTS2021_00059/nrrd2csv.csv with columns: ['Busyness', 'Coarseness', 'Complexity', 'Contrast', 'Strength']
# Saved CSV to: dataset/ngtdm/kernel5-radius5/non_tumor/BraTS2021_00060/nrrd2csv.csv with columns: ['Busyness', 'Coarseness', 'Complexity', 'Contrast', 'Strength']
# Saved CSV to: dataset/ngtdm/kernel5-radius5/non_tumor/BraTS2021_00061/nrrd2csv.csv with columns: ['Busyness', 'Coarseness', 'Complexity', 'Contrast', 'Strength']
# Saved CSV to: dataset/ngtdm/kernel5-radius5/non_tumor/BraTS2021_00062/nrrd2csv.csv with columns: ['Busyness', 'Coarseness', 'Complexity', 'Contrast', 'Strength']
# Saved CSV to: dataset/ngtdm/kernel5-radius5/non_tumor/BraTS2021_00063/nrrd2csv.csv with columns: ['Busyness', 'Coarseness', 'Complexity', 'Contrast', 'Strength']
# Saved CSV to: dataset/ngtdm/kernel5-radius5/non_tumor/BraTS2021_00064/nrrd2csv.csv with columns: ['Busyness', 'Coarseness', 'Complexity', 'Contrast', 'Strength']
# Saved CSV to: dataset/ngtdm/kernel5-radius5/non_tumor/BraTS2021_00066/nrrd2csv.csv with columns: ['Busyness', 'Coarseness', 'Complexity', 'Contrast', 'Strength']
# Saved CSV to: dataset/ngtdm/kernel5-radius5/non_tumor/BraTS2021_00068/nrrd2csv.csv with columns: ['Busyness', 'Coarseness', 'Complexity', 'Contrast', 'Strength']
# Saved CSV to: dataset/ngtdm/kernel5-radius5/non_tumor/BraTS2021_00070/nrrd2csv.csv with columns: ['Busyness', 'Coarseness', 'Complexity', 'Contrast', 'Strength']
# Saved CSV to: dataset/ngtdm/kernel5-radius5/non_tumor/BraTS2021_00071/nrrd2csv.csv with columns: ['Busyness', 'Coarseness', 'Complexity', 'Contrast', 'Strength']
# Saved CSV to: dataset/ngtdm/kernel5-radius5/non_tumor/BraTS2021_00072/nrrd2csv.csv with columns: ['Busyness', 'Coarseness', 'Complexity', 'Contrast', 'Strength']
# Saved CSV to: dataset/ngtdm/kernel5-radius5/non_tumor/BraTS2021_00074/nrrd2csv.csv with columns: ['Busyness', 'Coarseness', 'Complexity', 'Contrast', 'Strength']
# Saved CSV to: dataset/ngtdm/kernel5-radius5/non_tumor/BraTS2021_00077/nrrd2csv.csv with columns: ['Busyness', 'Coarseness', 'Complexity', 'Contrast', 'Strength']
# Saved CSV to: dataset/ngtdm/kernel5-radius5/non_tumor/BraTS2021_00078/nrrd2csv.csv with columns: ['Busyness', 'Coarseness', 'Complexity', 'Contrast', 'Strength']
# Saved CSV to: dataset/ngtdm/kernel5-radius5/non_tumor/BraTS2021_00081/nrrd2csv.csv with columns: ['Busyness', 'Coarseness', 'Complexity', 'Contrast', 'Strength']
# Saved CSV to: dataset/ngtdm/kernel5-radius5/non_tumor/BraTS2021_00084/nrrd2csv.csv with columns: ['Busyness', 'Coarseness', 'Complexity', 'Contrast', 'Strength']
# Saved CSV to: dataset/ngtdm/kernel5-radius5/non_tumor/BraTS2021_00085/nrrd2csv.csv with columns: ['Busyness', 'Coarseness', 'Complexity', 'Contrast', 'Strength']
# Saved CSV to: dataset/ngtdm/kernel5-radius5/non_tumor/BraTS2021_00087/nrrd2csv.csv with columns: ['Busyness', 'Coarseness', 'Complexity', 'Contrast', 'Strength']
# Saved CSV to: dataset/ngtdm/kernel5-radius5/non_tumor/BraTS2021_00088/nrrd2csv.csv with columns: ['Busyness', 'Coarseness', 'Complexity', 'Contrast', 'Strength']
# Saved CSV to: dataset/ngtdm/kernel5-radius5/non_tumor/BraTS2021_00089/nrrd2csv.csv with columns: ['Busyness', 'Coarseness', 'Complexity', 'Contrast', 'Strength']
# Saved CSV to: dataset/ngtdm/kernel5-radius5/non_tumor/BraTS2021_00090/nrrd2csv.csv with columns: ['Busyness', 'Coarseness', 'Complexity', 'Contrast', 'Strength']
# Saved CSV to: dataset/ngtdm/kernel5-radius5/non_tumor/BraTS2021_00094/nrrd2csv.csv with columns: ['Busyness', 'Coarseness', 'Complexity', 'Contrast', 'Strength']
# Saved CSV to: dataset/ngtdm/kernel5-radius5/non_tumor/BraTS2021_00095/nrrd2csv.csv with columns: ['Busyness', 'Coarseness', 'Complexity', 'Contrast', 'Strength']
# Saved CSV to: dataset/ngtdm/kernel5-radius5/non_tumor/BraTS2021_00096/nrrd2csv.csv with columns: ['Busyness', 'Coarseness', 'Complexity', 'Contrast', 'Strength']
# Saved CSV to: dataset/ngtdm/kernel5-radius5/non_tumor/BraTS2021_00097/nrrd2csv.csv with columns: ['Busyness', 'Coarseness', 'Complexity', 'Contrast', 'Strength']
# Saved CSV to: dataset/ngtdm/kernel5-radius5/non_tumor/BraTS2021_00098/nrrd2csv.csv with columns: ['Busyness', 'Coarseness', 'Complexity', 'Contrast', 'Strength']
# Saved CSV to: dataset/ngtdm/kernel5-radius5/non_tumor/BraTS2021_00099/nrrd2csv.csv with columns: ['Busyness', 'Coarseness', 'Complexity', 'Contrast', 'Strength']
# Saved CSV to: dataset/ngtdm/kernel5-radius5/non_tumor/BraTS2021_00100/nrrd2csv.csv with columns: ['Busyness', 'Coarseness', 'Complexity', 'Contrast', 'Strength']
# Saved CSV to: dataset/ngtdm/kernel5-radius5/non_tumor/BraTS2021_00101/nrrd2csv.csv with columns: ['Busyness', 'Coarseness', 'Complexity', 'Contrast', 'Strength']
# Saved CSV to: dataset/ngtdm/kernel5-radius5/non_tumor/BraTS2021_00102/nrrd2csv.csv with columns: ['Busyness', 'Coarseness', 'Complexity', 'Contrast', 'Strength']
# Saved CSV to: dataset/ngtdm/kernel5-radius5/non_tumor/BraTS2021_00103/nrrd2csv.csv with columns: ['Busyness', 'Coarseness', 'Complexity', 'Contrast', 'Strength']
# Saved CSV to: dataset/ngtdm/kernel5-radius5/non_tumor/BraTS2021_00104/nrrd2csv.csv with columns: ['Busyness', 'Coarseness', 'Complexity', 'Contrast', 'Strength']
# Saved CSV to: dataset/ngtdm/kernel5-radius5/non_tumor/BraTS2021_00105/nrrd2csv.csv with columns: ['Busyness', 'Coarseness', 'Complexity', 'Contrast', 'Strength']
# Saved CSV to: dataset/ngtdm/kernel5-radius5/non_tumor/BraTS2021_00106/nrrd2csv.csv with columns: ['Busyness', 'Coarseness', 'Complexity', 'Contrast', 'Strength']
# Saved CSV to: dataset/ngtdm/kernel5-radius5/non_tumor/BraTS2021_00107/nrrd2csv.csv with columns: ['Busyness', 'Coarseness', 'Complexity', 'Contrast', 'Strength']
# Saved CSV to: dataset/ngtdm/kernel5-radius5/non_tumor/BraTS2021_00108/nrrd2csv.csv with columns: ['Busyness', 'Coarseness', 'Complexity', 'Contrast', 'Strength']
# Saved CSV to: dataset/ngtdm/kernel5-radius5/non_tumor/BraTS2021_00109/nrrd2csv.csv with columns: ['Busyness', 'Coarseness', 'Complexity', 'Contrast', 'Strength']
# Saved CSV to: dataset/ngtdm/kernel5-radius5/non_tumor/BraTS2021_00110/nrrd2csv.csv with columns: ['Busyness', 'Coarseness', 'Complexity', 'Contrast', 'Strength']
# Saved CSV to: dataset/ngtdm/kernel5-radius5/non_tumor/BraTS2021_00111/nrrd2csv.csv with columns: ['Busyness', 'Coarseness', 'Complexity', 'Contrast', 'Strength']
# Saved CSV to: dataset/ngtdm/kernel5-radius5/non_tumor/BraTS2021_00112/nrrd2csv.csv with columns: ['Busyness', 'Coarseness', 'Complexity', 'Contrast', 'Strength']
# Saved CSV to: dataset/ngtdm/kernel5-radius5/non_tumor/BraTS2021_00113/nrrd2csv.csv with columns: ['Busyness', 'Coarseness', 'Complexity', 'Contrast', 'Strength']
# Saved CSV to: dataset/ngtdm/kernel5-radius5/non_tumor/BraTS2021_00115/nrrd2csv.csv with columns: ['Busyness', 'Coarseness', 'Complexity', 'Contrast', 'Strength']
# Saved CSV to: dataset/ngtdm/kernel5-radius5/non_tumor/BraTS2021_00116/nrrd2csv.csv with columns: ['Busyness', 'Coarseness', 'Complexity', 'Contrast', 'Strength']
# Saved CSV to: dataset/ngtdm/kernel5-radius5/non_tumor/BraTS2021_00117/nrrd2csv.csv with columns: ['Busyness', 'Coarseness', 'Complexity', 'Contrast', 'Strength']
# Saved CSV to: dataset/ngtdm/kernel5-radius5/non_tumor/BraTS2021_00118/nrrd2csv.csv with columns: ['Busyness', 'Coarseness', 'Complexity', 'Contrast', 'Strength']
# Saved CSV to: dataset/ngtdm/kernel5-radius5/non_tumor/BraTS2021_00120/nrrd2csv.csv with columns: ['Busyness', 'Coarseness', 'Complexity', 'Contrast', 'Strength']
# Saved CSV to: dataset/ngtdm/kernel5-radius5/non_tumor/BraTS2021_00121/nrrd2csv.csv with columns: ['Busyness', 'Coarseness', 'Complexity', 'Contrast', 'Strength']
# Saved CSV to: dataset/ngtdm/kernel5-radius5/non_tumor/BraTS2021_00122/nrrd2csv.csv with columns: ['Busyness', 'Coarseness', 'Complexity', 'Contrast', 'Strength']
# Saved CSV to: dataset/ngtdm/kernel5-radius5/non_tumor/BraTS2021_00123/nrrd2csv.csv with columns: ['Busyness', 'Coarseness', 'Complexity', 'Contrast', 'Strength']
# Saved CSV to: dataset/ngtdm/kernel5-radius5/non_tumor/BraTS2021_00124/nrrd2csv.csv with columns: ['Busyness', 'Coarseness', 'Complexity', 'Contrast', 'Strength']
# Saved CSV to: dataset/ngtdm/kernel5-radius5/non_tumor/BraTS2021_00126/nrrd2csv.csv with columns: ['Busyness', 'Coarseness', 'Complexity', 'Contrast', 'Strength']
# Saved CSV to: dataset/ngtdm/kernel5-radius5/non_tumor/BraTS2021_00127/nrrd2csv.csv with columns: ['Busyness', 'Coarseness', 'Complexity', 'Contrast', 'Strength']
# Saved CSV to: dataset/ngtdm/kernel5-radius5/non_tumor/BraTS2021_00128/nrrd2csv.csv with columns: ['Busyness', 'Coarseness', 'Complexity', 'Contrast', 'Strength']
# Saved CSV to: dataset/ngtdm/kernel5-radius5/non_tumor/BraTS2021_00130/nrrd2csv.csv with columns: ['Busyness', 'Coarseness', 'Complexity', 'Contrast', 'Strength']
# Saved CSV to: dataset/ngtdm/kernel5-radius5/non_tumor/BraTS2021_00131/nrrd2csv.csv with columns: ['Busyness', 'Coarseness', 'Complexity', 'Contrast', 'Strength']
# Saved CSV to: dataset/ngtdm/kernel5-radius5/non_tumor/BraTS2021_00132/nrrd2csv.csv with columns: ['Busyness', 'Coarseness', 'Complexity', 'Contrast', 'Strength']
# Saved CSV to: dataset/ngtdm/kernel5-radius5/non_tumor/BraTS2021_00133/nrrd2csv.csv with columns: ['Busyness', 'Coarseness', 'Complexity', 'Contrast', 'Strength']
# Saved CSV to: dataset/ngtdm/kernel5-radius5/non_tumor/BraTS2021_00134/nrrd2csv.csv with columns: ['Busyness', 'Coarseness', 'Complexity', 'Contrast', 'Strength']
# Saved CSV to: dataset/ngtdm/kernel5-radius5/non_tumor/BraTS2021_00136/nrrd2csv.csv with columns: ['Busyness', 'Coarseness', 'Complexity', 'Contrast', 'Strength']
# Saved CSV to: dataset/ngtdm/kernel5-radius5/non_tumor/BraTS2021_00137/nrrd2csv.csv with columns: ['Busyness', 'Coarseness', 'Complexity', 'Contrast', 'Strength']
# Saved CSV to: dataset/ngtdm/kernel5-radius5/non_tumor/BraTS2021_00138/nrrd2csv.csv with columns: ['Busyness', 'Coarseness', 'Complexity', 'Contrast', 'Strength']
# Saved CSV to: dataset/ngtdm/kernel5-radius5/non_tumor/BraTS2021_00139/nrrd2csv.csv with columns: ['Busyness', 'Coarseness', 'Complexity', 'Contrast', 'Strength']
# Saved CSV to: dataset/ngtdm/kernel5-radius5/non_tumor/BraTS2021_00140/nrrd2csv.csv with columns: ['Busyness', 'Coarseness', 'Complexity', 'Contrast', 'Strength']
# Saved CSV to: dataset/ngtdm/kernel5-radius5/non_tumor/BraTS2021_00142/nrrd2csv.csv with columns: ['Busyness', 'Coarseness', 'Complexity', 'Contrast', 'Strength']
# Saved CSV to: dataset/ngtdm/kernel5-radius5/non_tumor/BraTS2021_00143/nrrd2csv.csv with columns: ['Busyness', 'Coarseness', 'Complexity', 'Contrast', 'Strength']
# Saved CSV to: dataset/ngtdm/kernel5-radius5/non_tumor/BraTS2021_00144/nrrd2csv.csv with columns: ['Busyness', 'Coarseness', 'Complexity', 'Contrast', 'Strength']
# Saved CSV to: dataset/ngtdm/kernel5-radius5/non_tumor/BraTS2021_00146/nrrd2csv.csv with columns: ['Busyness', 'Coarseness', 'Complexity', 'Contrast', 'Strength']
# Saved CSV to: dataset/ngtdm/kernel5-radius5/non_tumor/BraTS2021_00147/nrrd2csv.csv with columns: ['Busyness', 'Coarseness', 'Complexity', 'Contrast', 'Strength']
# Saved CSV to: dataset/ngtdm/kernel5-radius5/non_tumor/BraTS2021_00148/nrrd2csv.csv with columns: ['Busyness', 'Coarseness', 'Complexity', 'Contrast', 'Strength']
# Saved CSV to: dataset/ngtdm/kernel5-radius5/non_tumor/BraTS2021_00149/nrrd2csv.csv with columns: ['Busyness', 'Coarseness', 'Complexity', 'Contrast', 'Strength']
# Saved CSV to: dataset/ngtdm/kernel5-radius5/non_tumor/BraTS2021_00150/nrrd2csv.csv with columns: ['Busyness', 'Coarseness', 'Complexity', 'Contrast', 'Strength']
# Saved CSV to: dataset/ngtdm/kernel5-radius5/non_tumor/BraTS2021_00151/nrrd2csv.csv with columns: ['Busyness', 'Coarseness', 'Complexity', 'Contrast', 'Strength']
# Saved CSV to: dataset/ngtdm/kernel5-radius5/non_tumor/BraTS2021_00152/nrrd2csv.csv with columns: ['Busyness', 'Coarseness', 'Complexity', 'Contrast', 'Strength']
# Saved CSV to: dataset/ngtdm/kernel5-radius5/non_tumor/BraTS2021_00154/nrrd2csv.csv with columns: ['Busyness', 'Coarseness', 'Complexity', 'Contrast', 'Strength']
# Saved CSV to: dataset/ngtdm/kernel5-radius5/non_tumor/BraTS2021_00155/nrrd2csv.csv with columns: ['Busyness', 'Coarseness', 'Complexity', 'Contrast', 'Strength']
# Saved CSV to: dataset/ngtdm/kernel5-radius5/non_tumor/BraTS2021_00156/nrrd2csv.csv with columns: ['Busyness', 'Coarseness', 'Complexity', 'Contrast', 'Strength']
# Saved CSV to: dataset/ngtdm/kernel5-radius5/non_tumor/BraTS2021_00157/nrrd2csv.csv with columns: ['Busyness', 'Coarseness', 'Complexity', 'Contrast', 'Strength']
# Saved CSV to: dataset/ngtdm/kernel5-radius5/non_tumor/BraTS2021_00158/nrrd2csv.csv with columns: ['Busyness', 'Coarseness', 'Complexity', 'Contrast', 'Strength']
# Saved CSV to: dataset/ngtdm/kernel5-radius5/non_tumor/BraTS2021_00159/nrrd2csv.csv with columns: ['Busyness', 'Coarseness', 'Complexity', 'Contrast', 'Strength']
# Saved CSV to: dataset/ngtdm/kernel5-radius5/non_tumor/BraTS2021_00160/nrrd2csv.csv with columns: ['Busyness', 'Coarseness', 'Complexity', 'Contrast', 'Strength']
# Saved CSV to: dataset/ngtdm/kernel5-radius5/non_tumor/BraTS2021_00162/nrrd2csv.csv with columns: ['Busyness', 'Coarseness', 'Complexity', 'Contrast', 'Strength']
# Saved CSV to: dataset/ngtdm/kernel5-radius5/non_tumor/BraTS2021_00165/nrrd2csv.csv with columns: ['Busyness', 'Coarseness', 'Complexity', 'Contrast', 'Strength']
# Saved CSV to: dataset/ngtdm/kernel5-radius5/non_tumor/BraTS2021_00166/nrrd2csv.csv with columns: ['Busyness', 'Coarseness', 'Complexity', 'Contrast', 'Strength']
# Saved CSV to: dataset/ngtdm/kernel5-radius5/non_tumor/BraTS2021_00167/nrrd2csv.csv with columns: ['Busyness', 'Coarseness', 'Complexity', 'Contrast', 'Strength']
# Saved CSV to: dataset/ngtdm/kernel5-radius5/non_tumor/BraTS2021_00170/nrrd2csv.csv with columns: ['Busyness', 'Coarseness', 'Complexity', 'Contrast', 'Strength']
# Saved CSV to: dataset/ngtdm/kernel5-radius5/non_tumor/BraTS2021_00171/nrrd2csv.csv with columns: ['Busyness', 'Coarseness', 'Complexity', 'Contrast', 'Strength']
# Saved CSV to: dataset/ngtdm/kernel5-radius5/non_tumor/BraTS2021_00172/nrrd2csv.csv with columns: ['Busyness', 'Coarseness', 'Complexity', 'Contrast', 'Strength']
# Saved CSV to: dataset/ngtdm/kernel5-radius5/non_tumor/BraTS2021_00176/nrrd2csv.csv with columns: ['Busyness', 'Coarseness', 'Complexity', 'Contrast', 'Strength']
# Saved CSV to: dataset/ngtdm/kernel5-radius5/non_tumor/BraTS2021_00177/nrrd2csv.csv with columns: ['Busyness', 'Coarseness', 'Complexity', 'Contrast', 'Strength']
# Saved CSV to: dataset/ngtdm/kernel5-radius5/non_tumor/BraTS2021_00178/nrrd2csv.csv with columns: ['Busyness', 'Coarseness', 'Complexity', 'Contrast', 'Strength']
# Saved CSV to: dataset/ngtdm/kernel5-radius5/non_tumor/BraTS2021_00183/nrrd2csv.csv with columns: ['Busyness', 'Coarseness', 'Complexity', 'Contrast', 'Strength']
# Saved CSV to: dataset/ngtdm/kernel5-radius5/non_tumor/BraTS2021_00184/nrrd2csv.csv with columns: ['Busyness', 'Coarseness', 'Complexity', 'Contrast', 'Strength']
# Saved CSV to: dataset/ngtdm/kernel5-radius5/non_tumor/BraTS2021_00185/nrrd2csv.csv with columns: ['Busyness', 'Coarseness', 'Complexity', 'Contrast', 'Strength']
# Saved CSV to: dataset/ngtdm/kernel5-radius5/non_tumor/BraTS2021_00186/nrrd2csv.csv with columns: ['Busyness', 'Coarseness', 'Complexity', 'Contrast', 'Strength']
# Saved CSV to: dataset/ngtdm/kernel5-radius5/non_tumor/BraTS2021_00187/nrrd2csv.csv with columns: ['Busyness', 'Coarseness', 'Complexity', 'Contrast', 'Strength']
# Saved CSV to: dataset/ngtdm/kernel5-radius5/non_tumor/BraTS2021_00188/nrrd2csv.csv with columns: ['Busyness', 'Coarseness', 'Complexity', 'Contrast', 'Strength']
# Saved CSV to: dataset/ngtdm/kernel5-radius5/non_tumor/BraTS2021_00191/nrrd2csv.csv with columns: ['Busyness', 'Coarseness', 'Complexity', 'Contrast', 'Strength']
# Saved CSV to: dataset/ngtdm/kernel5-radius5/non_tumor/BraTS2021_00192/nrrd2csv.csv with columns: ['Busyness', 'Coarseness', 'Complexity', 'Contrast', 'Strength']
# Saved CSV to: dataset/ngtdm/kernel5-radius5/non_tumor/BraTS2021_00193/nrrd2csv.csv with columns: ['Busyness', 'Coarseness', 'Complexity', 'Contrast', 'Strength']
# Saved CSV to: dataset/ngtdm/kernel5-radius5/non_tumor/BraTS2021_00194/nrrd2csv.csv with columns: ['Busyness', 'Coarseness', 'Complexity', 'Contrast', 'Strength']
# Saved CSV to: dataset/ngtdm/kernel5-radius5/non_tumor/BraTS2021_00195/nrrd2csv.csv with columns: ['Busyness', 'Coarseness', 'Complexity', 'Contrast', 'Strength']
# Saved CSV to: dataset/ngtdm/kernel5-radius5/non_tumor/BraTS2021_00196/nrrd2csv.csv with columns: ['Busyness', 'Coarseness', 'Complexity', 'Contrast', 'Strength']
# Saved CSV to: dataset/ngtdm/kernel5-radius5/non_tumor/BraTS2021_00199/nrrd2csv.csv with columns: ['Busyness', 'Coarseness', 'Complexity', 'Contrast', 'Strength']
# Saved CSV to: dataset/ngtdm/kernel5-radius5/non_tumor/BraTS2021_00201/nrrd2csv.csv with columns: ['Busyness', 'Coarseness', 'Complexity', 'Contrast', 'Strength']
# Saved CSV to: dataset/ngtdm/kernel5-radius5/non_tumor/BraTS2021_00203/nrrd2csv.csv with columns: ['Busyness', 'Coarseness', 'Complexity', 'Contrast', 'Strength']
# Saved CSV to: dataset/ngtdm/kernel5-radius5/non_tumor/BraTS2021_00204/nrrd2csv.csv with columns: ['Busyness', 'Coarseness', 'Complexity', 'Contrast', 'Strength']
# Saved CSV to: dataset/ngtdm/kernel5-radius5/non_tumor/BraTS2021_00206/nrrd2csv.csv with columns: ['Busyness', 'Coarseness', 'Complexity', 'Contrast', 'Strength']
# Saved CSV to: dataset/ngtdm/kernel5-radius5/non_tumor/BraTS2021_00207/nrrd2csv.csv with columns: ['Busyness', 'Coarseness', 'Complexity', 'Contrast', 'Strength']
# Saved CSV to: dataset/ngtdm/kernel5-radius5/non_tumor/BraTS2021_00209/nrrd2csv.csv with columns: ['Busyness', 'Coarseness', 'Complexity', 'Contrast', 'Strength']
# Saved CSV to: dataset/ngtdm/kernel5-radius5/non_tumor/BraTS2021_00210/nrrd2csv.csv with columns: ['Busyness', 'Coarseness', 'Complexity', 'Contrast', 'Strength']
# Saved CSV to: dataset/ngtdm/kernel5-radius5/non_tumor/BraTS2021_00211/nrrd2csv.csv with columns: ['Busyness', 'Coarseness', 'Complexity', 'Contrast', 'Strength']
# Saved CSV to: dataset/ngtdm/kernel5-radius5/non_tumor/BraTS2021_00212/nrrd2csv.csv with columns: ['Busyness', 'Coarseness', 'Complexity', 'Contrast', 'Strength']
# Saved CSV to: dataset/ngtdm/kernel5-radius5/non_tumor/BraTS2021_00214/nrrd2csv.csv with columns: ['Busyness', 'Coarseness', 'Complexity', 'Contrast', 'Strength']
# Saved CSV to: dataset/ngtdm/kernel5-radius5/non_tumor/BraTS2021_00216/nrrd2csv.csv with columns: ['Busyness', 'Coarseness', 'Complexity', 'Contrast', 'Strength']
# Saved CSV to: dataset/ngtdm/kernel5-radius5/non_tumor/BraTS2021_00217/nrrd2csv.csv with columns: ['Busyness', 'Coarseness', 'Complexity', 'Contrast', 'Strength']
# Saved CSV to: dataset/ngtdm/kernel5-radius5/non_tumor/BraTS2021_00218/nrrd2csv.csv with columns: ['Busyness', 'Coarseness', 'Complexity', 'Contrast', 'Strength']
# Saved CSV to: dataset/ngtdm/kernel5-radius5/non_tumor/BraTS2021_00219/nrrd2csv.csv with columns: ['Busyness', 'Coarseness', 'Complexity', 'Contrast', 'Strength']
# Saved CSV to: dataset/ngtdm/kernel5-radius5/non_tumor/BraTS2021_00220/nrrd2csv.csv with columns: ['Busyness', 'Coarseness', 'Complexity', 'Contrast', 'Strength']
# Saved CSV to: dataset/ngtdm/kernel5-radius5/non_tumor/BraTS2021_00221/nrrd2csv.csv with columns: ['Busyness', 'Coarseness', 'Complexity', 'Contrast', 'Strength']
# Saved CSV to: dataset/ngtdm/kernel5-radius5/non_tumor/BraTS2021_00222/nrrd2csv.csv with columns: ['Busyness', 'Coarseness', 'Complexity', 'Contrast', 'Strength']
# Saved CSV to: dataset/ngtdm/kernel5-radius5/non_tumor/BraTS2021_00227/nrrd2csv.csv with columns: ['Busyness', 'Coarseness', 'Complexity', 'Contrast', 'Strength']
# Saved CSV to: dataset/ngtdm/kernel5-radius5/non_tumor/BraTS2021_00228/nrrd2csv.csv with columns: ['Busyness', 'Coarseness', 'Complexity', 'Contrast', 'Strength']
# Saved CSV to: dataset/ngtdm/kernel5-radius5/non_tumor/BraTS2021_00230/nrrd2csv.csv with columns: ['Busyness', 'Coarseness', 'Complexity', 'Contrast', 'Strength']
# Saved CSV to: dataset/ngtdm/kernel5-radius5/non_tumor/BraTS2021_00231/nrrd2csv.csv with columns: ['Busyness', 'Coarseness', 'Complexity', 'Contrast', 'Strength']
# Saved CSV to: dataset/ngtdm/kernel5-radius5/non_tumor/BraTS2021_00233/nrrd2csv.csv with columns: ['Busyness', 'Coarseness', 'Complexity', 'Contrast', 'Strength']
# Saved CSV to: dataset/ngtdm/kernel5-radius5/non_tumor/BraTS2021_00234/nrrd2csv.csv with columns: ['Busyness', 'Coarseness', 'Complexity', 'Contrast', 'Strength']
# Saved CSV to: dataset/ngtdm/kernel5-radius5/non_tumor/BraTS2021_00235/nrrd2csv.csv with columns: ['Busyness', 'Coarseness', 'Complexity', 'Contrast', 'Strength']
# Saved CSV to: dataset/ngtdm/kernel5-radius5/non_tumor/BraTS2021_00236/nrrd2csv.csv with columns: ['Busyness', 'Coarseness', 'Complexity', 'Contrast', 'Strength']
# Saved CSV to: dataset/ngtdm/kernel5-radius5/non_tumor/BraTS2021_00237/nrrd2csv.csv with columns: ['Busyness', 'Coarseness', 'Complexity', 'Contrast', 'Strength']
# Saved CSV to: dataset/ngtdm/kernel5-radius5/non_tumor/BraTS2021_00238/nrrd2csv.csv with columns: ['Busyness', 'Coarseness', 'Complexity', 'Contrast', 'Strength']
# Saved CSV to: dataset/ngtdm/kernel5-radius5/non_tumor/BraTS2021_00239/nrrd2csv.csv with columns: ['Busyness', 'Coarseness', 'Complexity', 'Contrast', 'Strength']
# Saved CSV to: dataset/ngtdm/kernel5-radius5/non_tumor/BraTS2021_00240/nrrd2csv.csv with columns: ['Busyness', 'Coarseness', 'Complexity', 'Contrast', 'Strength']
# Saved CSV to: dataset/ngtdm/kernel5-radius5/non_tumor/BraTS2021_00241/nrrd2csv.csv with columns: ['Busyness', 'Coarseness', 'Complexity', 'Contrast', 'Strength']
# Saved CSV to: dataset/ngtdm/kernel5-radius5/non_tumor/BraTS2021_00242/nrrd2csv.csv with columns: ['Busyness', 'Coarseness', 'Complexity', 'Contrast', 'Strength']
# Saved CSV to: dataset/ngtdm/kernel5-radius5/non_tumor/BraTS2021_00243/nrrd2csv.csv with columns: ['Busyness', 'Coarseness', 'Complexity', 'Contrast', 'Strength']
# Saved CSV to: dataset/ngtdm/kernel5-radius5/non_tumor/BraTS2021_00246/nrrd2csv.csv with columns: ['Busyness', 'Coarseness', 'Complexity', 'Contrast', 'Strength']
# Saved CSV to: dataset/ngtdm/kernel5-radius5/non_tumor/BraTS2021_00247/nrrd2csv.csv with columns: ['Busyness', 'Coarseness', 'Complexity', 'Contrast', 'Strength']
# Saved CSV to: dataset/ngtdm/kernel5-radius5/non_tumor/BraTS2021_00249/nrrd2csv.csv with columns: ['Busyness', 'Coarseness', 'Complexity', 'Contrast', 'Strength']
# Saved CSV to: dataset/ngtdm/kernel5-radius5/non_tumor/BraTS2021_00250/nrrd2csv.csv with columns: ['Busyness', 'Coarseness', 'Complexity', 'Contrast', 'Strength']
# Saved CSV to: dataset/ngtdm/kernel5-radius5/non_tumor/BraTS2021_00251/nrrd2csv.csv with columns: ['Busyness', 'Coarseness', 'Complexity', 'Contrast', 'Strength']
# Saved CSV to: dataset/ngtdm/kernel5-radius5/non_tumor/BraTS2021_00253/nrrd2csv.csv with columns: ['Busyness', 'Coarseness', 'Complexity', 'Contrast', 'Strength']
# Saved CSV to: dataset/ngtdm/kernel5-radius5/non_tumor/BraTS2021_00254/nrrd2csv.csv with columns: ['Busyness', 'Coarseness', 'Complexity', 'Contrast', 'Strength']
# Saved CSV to: dataset/ngtdm/kernel5-radius5/non_tumor/BraTS2021_00258/nrrd2csv.csv with columns: ['Busyness', 'Coarseness', 'Complexity', 'Contrast', 'Strength']
# Saved CSV to: dataset/ngtdm/kernel5-radius5/non_tumor/BraTS2021_00259/nrrd2csv.csv with columns: ['Busyness', 'Coarseness', 'Complexity', 'Contrast', 'Strength']
# Saved CSV to: dataset/ngtdm/kernel5-radius5/non_tumor/BraTS2021_00260/nrrd2csv.csv with columns: ['Busyness', 'Coarseness', 'Complexity', 'Contrast', 'Strength']
# Saved CSV to: dataset/ngtdm/kernel5-radius5/non_tumor/BraTS2021_00261/nrrd2csv.csv with columns: ['Busyness', 'Coarseness', 'Complexity', 'Contrast', 'Strength']
# Saved CSV to: dataset/ngtdm/kernel5-radius5/non_tumor/BraTS2021_00262/nrrd2csv.csv with columns: ['Busyness', 'Coarseness', 'Complexity', 'Contrast', 'Strength']
# Saved CSV to: dataset/ngtdm/kernel5-radius5/non_tumor/BraTS2021_00263/nrrd2csv.csv with columns: ['Busyness', 'Coarseness', 'Complexity', 'Contrast', 'Strength']
# Saved CSV to: dataset/ngtdm/kernel5-radius5/non_tumor/BraTS2021_00266/nrrd2csv.csv with columns: ['Busyness', 'Coarseness', 'Complexity', 'Contrast', 'Strength']
# Saved CSV to: dataset/ngtdm/kernel5-radius5/non_tumor/BraTS2021_00267/nrrd2csv.csv with columns: ['Busyness', 'Coarseness', 'Complexity', 'Contrast', 'Strength']
# Saved CSV to: dataset/ngtdm/kernel5-radius5/non_tumor/BraTS2021_00269/nrrd2csv.csv with columns: ['Busyness', 'Coarseness', 'Complexity', 'Contrast', 'Strength']
# Saved CSV to: dataset/ngtdm/kernel5-radius5/non_tumor/BraTS2021_00270/nrrd2csv.csv with columns: ['Busyness', 'Coarseness', 'Complexity', 'Contrast', 'Strength']
# Saved CSV to: dataset/ngtdm/kernel5-radius5/non_tumor/BraTS2021_00271/nrrd2csv.csv with columns: ['Busyness', 'Coarseness', 'Complexity', 'Contrast', 'Strength']
# Saved CSV to: dataset/ngtdm/kernel5-radius5/non_tumor/BraTS2021_00273/nrrd2csv.csv with columns: ['Busyness', 'Coarseness', 'Complexity', 'Contrast', 'Strength']
# Saved CSV to: dataset/ngtdm/kernel5-radius5/non_tumor/BraTS2021_00274/nrrd2csv.csv with columns: ['Busyness', 'Coarseness', 'Complexity', 'Contrast', 'Strength']
# Saved CSV to: dataset/ngtdm/kernel5-radius5/non_tumor/BraTS2021_00275/nrrd2csv.csv with columns: ['Busyness', 'Coarseness', 'Complexity', 'Contrast', 'Strength']
# Saved CSV to: dataset/ngtdm/kernel5-radius5/non_tumor/BraTS2021_00280/nrrd2csv.csv with columns: ['Busyness', 'Coarseness', 'Complexity', 'Contrast', 'Strength']
# Saved CSV to: dataset/ngtdm/kernel5-radius5/non_tumor/BraTS2021_00281/nrrd2csv.csv with columns: ['Busyness', 'Coarseness', 'Complexity', 'Contrast', 'Strength']
# Saved CSV to: dataset/ngtdm/kernel5-radius5/non_tumor/BraTS2021_00282/nrrd2csv.csv with columns: ['Busyness', 'Coarseness', 'Complexity', 'Contrast', 'Strength']
# Saved CSV to: dataset/ngtdm/kernel5-radius5/non_tumor/BraTS2021_00283/nrrd2csv.csv with columns: ['Busyness', 'Coarseness', 'Complexity', 'Contrast', 'Strength']
# Saved CSV to: dataset/ngtdm/kernel5-radius5/non_tumor/BraTS2021_00284/nrrd2csv.csv with columns: ['Busyness', 'Coarseness', 'Complexity', 'Contrast', 'Strength']
# Saved CSV to: dataset/ngtdm/kernel5-radius5/non_tumor/BraTS2021_00285/nrrd2csv.csv with columns: ['Busyness', 'Coarseness', 'Complexity', 'Contrast', 'Strength']

# %%
import os
import pandas as pd
from pathlib import Path

datasetPath = rootPath + 'non_tumor'
dfs: list[pd.DataFrame] = []

patientFolders = os.listdir(datasetPath)
patientFolders.sort()
for patientFolder in patientFolders:
  if patientFolder.startswith('BraTS2021_'):
    csvPath = f"{datasetPath}/{patientFolder}/nrrd2csv.csv"
    df = pd.read_csv(csvPath)
    df.insert(0, 'label', 0)
    dfs.append(df)

merged = pd.concat(dfs, ignore_index=True)
output_merged = rootPath + 'non_tumor/dataset.csv'
Path(output_merged).parent.mkdir(parents=True, exist_ok=True)
merged.to_csv(output_merged, index=False)

# %%
import os
import pandas as pd
from pathlib import Path

datasetPath = rootPath + 'tumor'
dfs: list[pd.DataFrame] = []

patientFolders = os.listdir(datasetPath)
patientFolders.sort()
for patientFolder in patientFolders:
  if patientFolder.startswith('BraTS2021_'):
    csvPath = f"{datasetPath}/{patientFolder}/nrrd2csv.csv"
    df = pd.read_csv(csvPath)
    df.insert(0, 'label', 1)
    dfs.append(df)

merged = pd.concat(dfs, ignore_index=True)
output_merged = rootPath + 'tumor/dataset.csv'
Path(output_merged).parent.mkdir(parents=True, exist_ok=True)
merged.to_csv(output_merged, index=False)

# %%
import pandas as pd
from pathlib import Path

tumorDf = pd.read_csv(rootPath + 'tumor/dataset.csv')
nonTumorDf = pd.read_csv(rootPath + 'non_tumor/dataset.csv')

merged = pd.concat([tumorDf, nonTumorDf], ignore_index=True)
merged = merged.sample(frac=1)  # Shuffle the dataset
output_merged = rootPath + 'dataset.200p.csv'
Path(output_merged).parent.mkdir(parents=True, exist_ok=True)
merged.to_csv(output_merged, index=False)
