# %%
# Import packages and modules
import numpy  as np
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow_decision_forests as tfdf

from sklearn.model_selection import train_test_split
# Out:
# 2026-05-26 17:45:36.235409: I tensorflow/core/util/port.cc:113] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2026-05-26 17:45:36.342559: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2026-05-26 17:45:38.371530: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
# Check the version of TensorFlow Decision Forests
print("Found TensorFlow Decision Forests v" + tfdf.__version__)
# Out:
# Found TensorFlow Decision Forests v1.9.1

# %%
# train/validation/test = 70/10/20
dataset = pd.read_csv('dataset/glszm/kernel5-radius5/dataset.csv')

train_data, temp_data = train_test_split(
    dataset, test_size=0.3, random_state=42
 )
validation_data, test_data = train_test_split(
    temp_data, test_size=2/3, random_state=42
 )

# %%
from sklearn.utils.class_weight import compute_class_weight

# tinh class weight tren tap train
classes = np.array([0, 1])
weights = compute_class_weight(class_weight="balanced", classes=classes, y=train_data["label"])
class_weight = {0: weights[0], 1: weights[1]}

# gan sample_weight cho tung dong
train_data["sample_weight"] = train_data["label"].map(class_weight)
validation_data["sample_weight"] = validation_data["label"].map(class_weight)
test_data["sample_weight"] = test_data["label"].map(class_weight)

# Convert the dataset into a TensorFlow dataset.
train_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    train_data, label="label", weight="sample_weight"
)         
val_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    validation_data, label="label", weight="sample_weight"
)
test_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    test_data, label="label", weight="sample_weight"
)
# Out:
# 2026-05-26 17:45:42.750136: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:984] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2026-05-26 17:45:42.750676: W tensorflow/core/common_runtime/gpu/gpu_device.cc:2251] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...

# %%
import keras

# %%
# %%time

# Train a Random Forest model.
model = tfdf.keras.RandomForestModel()

# Add evaluation metrics
model.compile(
    metrics=["accuracy"]
)
model.fit(x=train_ds)

# # Train a Gradient Boosted Trees model.
# model = tfdf.keras.GradientBoostedTreesModel(num_trees=1500)
# model.fit(train_ds)
# Out:
# Use /tmp/tmptrcb00hb as temporary training directory
# Reading training dataset...
# Training dataset read in 0:00:03.991192. Found 78712 examples.
# Training model...
# [INFO 26-05-26 17:46:01.5824 UTC kernel.cc:1233] Loading model from path /tmp/tmptrcb00hb/model/ with prefix 05e9b856ffa24e15
# Model trained in 0:00:16.058338
# Compiling model...
# [INFO 26-05-26 17:46:03.1791 UTC decision_forest.cc:734] Model loaded with 300 root(s), 693732 node(s), and 16 input feature(s).
# [INFO 26-05-26 17:46:03.1791 UTC abstract_model.cc:1362] Engine "RandomForestOptPred" built
# [INFO 26-05-26 17:46:03.1791 UTC kernel.cc:1061] Use fast generic engine
# Model compiled.
# CPU times: user 1min 36s, sys: 2.02 s, total: 1min 38s
# Wall time: 24.7 s

# %%
# Evaluate the model
evaluate = model.evaluate(val_ds, return_dict=True)
print()

for name, value in evaluate.items():
    print(f"{name}: {value:.4f}")
# Out:
# WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 12/12 [==============================] - 4s 33ms/step - loss: 0.0000e+00 - accuracy: 0.9491
#
# loss: 0.0000
# accuracy: 0.9491

# %%
# Model Summary
model.summary()
# Out:
# Model: "random_forest_model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
# =================================================================
# Total params: 1 (1.00 Byte)
# Trainable params: 0 (0.00 Byte)
# Non-trainable params: 1 (1.00 Byte)
# _________________________________________________________________
# Type: "RANDOM_FOREST"
# Task: CLASSIFICATION
# Label: "__LABEL"
#
# Input Features (16):
# 	GrayLevelNonUniformity
# 	GrayLevelNonUniformityNormalized
# 	GrayLevelVariance
# 	HighGrayLevelZoneEmphasis
# 	LargeAreaEmphasis
# 	LargeAreaHighGrayLevelEmphasis
# 	LargeAreaLowGrayLevelEmphasis
# 	LowGrayLevelZoneEmphasis
# 	SizeZoneNonUniformity
# 	SizeZoneNonUniformityNormalized
# 	SmallAreaEmphasis
# 	SmallAreaHighGrayLevelEmphasis
# 	SmallAreaLowGrayLevelEmphasis
# 	ZoneEntropy
# 	ZonePercentage
# 	ZoneVariance
#
# Trained with weights
#
# Variable Importance: INV_MEAN_MIN_DEPTH:
#     1.        "HighGrayLevelZoneEmphasis"  0.202478 ################
#     2.           "GrayLevelNonUniformity"  0.164961 ##########
#     3.   "SmallAreaHighGrayLevelEmphasis"  0.134617 ######
#     4.         "LowGrayLevelZoneEmphasis"  0.132038 ######
#     5.   "LargeAreaHighGrayLevelEmphasis"  0.130970 ######
#     6.    "LargeAreaLowGrayLevelEmphasis"  0.118168 ####
#     7.    "SmallAreaLowGrayLevelEmphasis"  0.117340 ####
#     8.                      "ZoneEntropy"  0.107580 ###
#     9.  "SizeZoneNonUniformityNormalized"  0.102817 ##
#    10.                "SmallAreaEmphasis"  0.094735 #
#    11.            "SizeZoneNonUniformity"  0.092678 #
#    12. "GrayLevelNonUniformityNormalized"  0.091259
#    13.                     "ZoneVariance"  0.089816
#    14.                "GrayLevelVariance"  0.089625
#    15.                   "ZonePercentage"  0.085446
#    16.                "LargeAreaEmphasis"  0.085015
#
# Variable Importance: NUM_AS_ROOT:
#     1.        "HighGrayLevelZoneEmphasis" 85.000000 ################
#     2.   "SmallAreaHighGrayLevelEmphasis" 83.000000 ###############
#     3.         "LowGrayLevelZoneEmphasis" 48.000000 ########
#     4.    "SmallAreaLowGrayLevelEmphasis" 30.000000 #####
#     5.    "LargeAreaLowGrayLevelEmphasis" 25.000000 ####
#     6.                      "ZoneEntropy" 15.000000 ##
#     7.           "GrayLevelNonUniformity"  6.000000
#     8.   "LargeAreaHighGrayLevelEmphasis"  5.000000
#     9.                "GrayLevelVariance"  2.000000
#    10. "GrayLevelNonUniformityNormalized"  1.000000
#
# Variable Importance: NUM_NODES:
#     1.    "LargeAreaLowGrayLevelEmphasis" 27233.000000 ################
#     2.   "LargeAreaHighGrayLevelEmphasis" 26891.000000 ###############
#     3.           "GrayLevelNonUniformity" 26839.000000 ###############
#     4.        "HighGrayLevelZoneEmphasis" 24256.000000 ###########
#     5.         "LowGrayLevelZoneEmphasis" 23259.000000 ##########
#     6.                      "ZoneEntropy" 22517.000000 #########
#     7.                "GrayLevelVariance" 21931.000000 ########
#     8.                     "ZoneVariance" 21341.000000 #######
#     9.   "SmallAreaHighGrayLevelEmphasis" 21147.000000 #######
#    10. "GrayLevelNonUniformityNormalized" 21136.000000 ######
#    11.    "SmallAreaLowGrayLevelEmphasis" 20765.000000 ######
#    12.                "LargeAreaEmphasis" 18998.000000 ###
#    13.            "SizeZoneNonUniformity" 18142.000000 ##
#    14.  "SizeZoneNonUniformityNormalized" 18016.000000 ##
#    15.                "SmallAreaEmphasis" 17844.000000 ##
#    16.                   "ZonePercentage" 16401.000000
#
# Variable Importance: SUM_SCORE:
#     1.        "HighGrayLevelZoneEmphasis" 2392037.026515 ################
#     2.   "SmallAreaHighGrayLevelEmphasis" 1522859.818238 #########
#     3.           "GrayLevelNonUniformity" 1485736.116369 ########
#     4.         "LowGrayLevelZoneEmphasis" 1247575.192747 #######
#     5.   "LargeAreaHighGrayLevelEmphasis" 1049208.542327 #####
#     6.    "SmallAreaLowGrayLevelEmphasis" 950287.960972 ####
#     7.    "LargeAreaLowGrayLevelEmphasis" 937509.103339 ####
#     8.                      "ZoneEntropy" 797173.836622 ###
#     9.  "SizeZoneNonUniformityNormalized" 556488.772855 #
#    10. "GrayLevelNonUniformityNormalized" 472632.160700 #
#    11.                "SmallAreaEmphasis" 456573.754269 #
#    12.            "SizeZoneNonUniformity" 448270.132072
#    13.                "GrayLevelVariance" 446802.984120
#    14.                     "ZoneVariance" 441659.524443
#    15.                "LargeAreaEmphasis" 336914.630533
#    16.                   "ZonePercentage" 321981.106577
#
#
#
# Winner takes all: true
# Out-of-bag evaluation: accuracy:0.843947 logloss:0.43505
# Number of trees: 300
# Total number of nodes: 693732
#
# Number of nodes by tree:
# Count: 300 Average: 2312.44 StdDev: 162.65
# Min: 1831 Max: 2641 Ignored: 0
# ----------------------------------------------
# [ 1831, 1871)  1   0.33%   0.33%
# [ 1871, 1912)  3   1.00%   1.33% #
# [ 1912, 1952)  6   2.00%   3.33% ##
# [ 1952, 1993)  3   1.00%   4.33% #
# [ 1993, 2033)  4   1.33%   5.67% #
# [ 2033, 2074) 10   3.33%   9.00% ###
# [ 2074, 2114)  8   2.67%  11.67% ##
# [ 2114, 2155) 12   4.00%  15.67% ###
# [ 2155, 2195) 26   8.67%  24.33% #######
# [ 2195, 2236) 17   5.67%  30.00% #####
# [ 2236, 2277) 21   7.00%  37.00% ######
# [ 2277, 2317) 28   9.33%  46.33% ########
# [ 2317, 2358) 31  10.33%  56.67% ########
# [ 2358, 2398) 37  12.33%  69.00% ##########
# [ 2398, 2439) 25   8.33%  77.33% #######
# [ 2439, 2479) 24   8.00%  85.33% ######
# [ 2479, 2520) 16   5.33%  90.67% ####
# [ 2520, 2560) 14   4.67%  95.33% ####
# [ 2560, 2601)  6   2.00%  97.33% ##
# [ 2601, 2641]  8   2.67% 100.00% ##
#
# Depth by leafs:
# Count: 347016 Average: 12.4348 StdDev: 2.30842
# Min: 3 Max: 15 Ignored: 0
# ----------------------------------------------
# [  3,  4)    11   0.00%   0.00%
# [  4,  5)   193   0.06%   0.06%
# [  5,  6)   992   0.29%   0.34%
# [  6,  7)  2921   0.84%   1.19%
# [  7,  8)  6621   1.91%   3.09% #
# [  8,  9) 12324   3.55%   6.65% #
# [  9, 10) 20091   5.79%  12.44% ##
# [ 10, 11) 29449   8.49%  20.92% ###
# [ 11, 12) 38566  11.11%  32.04% ####
# [ 12, 13) 46121  13.29%  45.33% #####
# [ 13, 14) 50284  14.49%  59.82% ######
# [ 14, 15) 51477  14.83%  74.65% ######
# [ 15, 15] 87966  25.35% 100.00% ##########
#
# Number of training obs by leaf:
# Count: 347016 Average: 68.0476 StdDev: 317.437
# Min: 5 Max: 12759 Ignored: 0
# ----------------------------------------------
# [     5,   642) 340772  98.20%  98.20% ##########
# [   642,  1280)   3517   1.01%  99.21%
# [  1280,  1918)   1065   0.31%  99.52%
# [  1918,  2556)    583   0.17%  99.69%
# [  2556,  3193)    294   0.08%  99.77%
# [  3193,  3831)    217   0.06%  99.84%
# [  3831,  4469)    131   0.04%  99.87%
# [  4469,  5107)     96   0.03%  99.90%
# [  5107,  5744)    120   0.03%  99.94%
# [  5744,  6382)     65   0.02%  99.96%
# [  6382,  7020)     59   0.02%  99.97%
# [  7020,  7658)     26   0.01%  99.98%
# [  7658,  8295)     23   0.01%  99.99%
# [  8295,  8933)     10   0.00%  99.99%
# [  8933,  9571)     11   0.00%  99.99%
# [  9571, 10209)      6   0.00%  99.99%
# [ 10209, 10846)     10   0.00% 100.00%
# [ 10846, 11484)      3   0.00% 100.00%
# [ 11484, 12122)      5   0.00% 100.00%
# [ 12122, 12759]      3   0.00% 100.00%
#
# Attribute in nodes:
# 	27233 : LargeAreaLowGrayLevelEmphasis [NUMERICAL]
# 	26891 : LargeAreaHighGrayLevelEmphasis [NUMERICAL]
# 	26839 : GrayLevelNonUniformity [NUMERICAL]
# 	24256 : HighGrayLevelZoneEmphasis [NUMERICAL]
# 	23259 : LowGrayLevelZoneEmphasis [NUMERICAL]
# 	22517 : ZoneEntropy [NUMERICAL]
# 	21931 : GrayLevelVariance [NUMERICAL]
# 	21341 : ZoneVariance [NUMERICAL]
# 	21147 : SmallAreaHighGrayLevelEmphasis [NUMERICAL]
# 	21136 : GrayLevelNonUniformityNormalized [NUMERICAL]
# 	20765 : SmallAreaLowGrayLevelEmphasis [NUMERICAL]
# 	18998 : LargeAreaEmphasis [NUMERICAL]
# 	18142 : SizeZoneNonUniformity [NUMERICAL]
# 	18016 : SizeZoneNonUniformityNormalized [NUMERICAL]
# 	17844 : SmallAreaEmphasis [NUMERICAL]
# 	16401 : ZonePercentage [NUMERICAL]
#
# Attribute in nodes with depth <= 0:
# 	85 : HighGrayLevelZoneEmphasis [NUMERICAL]
# 	83 : SmallAreaHighGrayLevelEmphasis [NUMERICAL]
# 	48 : LowGrayLevelZoneEmphasis [NUMERICAL]
# 	30 : SmallAreaLowGrayLevelEmphasis [NUMERICAL]
# 	25 : LargeAreaLowGrayLevelEmphasis [NUMERICAL]
# 	15 : ZoneEntropy [NUMERICAL]
# 	6 : GrayLevelNonUniformity [NUMERICAL]
# 	5 : LargeAreaHighGrayLevelEmphasis [NUMERICAL]
# 	2 : GrayLevelVariance [NUMERICAL]
# 	1 : GrayLevelNonUniformityNormalized [NUMERICAL]
#
# Attribute in nodes with depth <= 1:
# 	220 : HighGrayLevelZoneEmphasis [NUMERICAL]
# 	142 : SmallAreaHighGrayLevelEmphasis [NUMERICAL]
# 	114 : LowGrayLevelZoneEmphasis [NUMERICAL]
# 	93 : GrayLevelNonUniformity [NUMERICAL]
# 	86 : LargeAreaHighGrayLevelEmphasis [NUMERICAL]
# 	69 : SmallAreaLowGrayLevelEmphasis [NUMERICAL]
# 	42 : SizeZoneNonUniformityNormalized [NUMERICAL]
# 	38 : ZoneEntropy [NUMERICAL]
# 	34 : LargeAreaLowGrayLevelEmphasis [NUMERICAL]
# 	23 : SmallAreaEmphasis [NUMERICAL]
# 	13 : SizeZoneNonUniformity [NUMERICAL]
# 	9 : ZonePercentage [NUMERICAL]
# 	5 : LargeAreaEmphasis [NUMERICAL]
# 	5 : GrayLevelVariance [NUMERICAL]
# 	4 : ZoneVariance [NUMERICAL]
# 	3 : GrayLevelNonUniformityNormalized [NUMERICAL]
#
# Attribute in nodes with depth <= 2:
# 	480 : HighGrayLevelZoneEmphasis [NUMERICAL]
# 	269 : LowGrayLevelZoneEmphasis [NUMERICAL]
# 	244 : GrayLevelNonUniformity [NUMERICAL]
# 	225 : SmallAreaHighGrayLevelEmphasis [NUMERICAL]
# 	209 : SmallAreaLowGrayLevelEmphasis [NUMERICAL]
# 	177 : LargeAreaHighGrayLevelEmphasis [NUMERICAL]
# 	144 : ZoneEntropy [NUMERICAL]
# 	105 : LargeAreaLowGrayLevelEmphasis [NUMERICAL]
# 	66 : SizeZoneNonUniformityNormalized [NUMERICAL]
# 	41 : GrayLevelNonUniformityNormalized [NUMERICAL]
# 	40 : SmallAreaEmphasis [NUMERICAL]
# 	30 : SizeZoneNonUniformity [NUMERICAL]
# 	26 : GrayLevelVariance [NUMERICAL]
# 	17 : ZonePercentage [NUMERICAL]
# 	15 : ZoneVariance [NUMERICAL]
# 	12 : LargeAreaEmphasis [NUMERICAL]
#
# Attribute in nodes with depth <= 3:
# 	804 : HighGrayLevelZoneEmphasis [NUMERICAL]
# 	580 : GrayLevelNonUniformity [NUMERICAL]
# 	512 : LowGrayLevelZoneEmphasis [NUMERICAL]
# 	431 : LargeAreaHighGrayLevelEmphasis [NUMERICAL]
# 	396 : SmallAreaLowGrayLevelEmphasis [NUMERICAL]
# 	329 : ZoneEntropy [NUMERICAL]
# 	323 : SmallAreaHighGrayLevelEmphasis [NUMERICAL]
# 	233 : LargeAreaLowGrayLevelEmphasis [NUMERICAL]
# 	149 : SizeZoneNonUniformityNormalized [NUMERICAL]
# 	129 : GrayLevelNonUniformityNormalized [NUMERICAL]
# 	120 : SmallAreaEmphasis [NUMERICAL]
# 	116 : GrayLevelVariance [NUMERICAL]
# 	110 : SizeZoneNonUniformity [NUMERICAL]
# 	96 : ZoneVariance [NUMERICAL]
# 	82 : LargeAreaEmphasis [NUMERICAL]
# 	79 : ZonePercentage [NUMERICAL]
#
# Attribute in nodes with depth <= 5:
# 	2146 : HighGrayLevelZoneEmphasis [NUMERICAL]
# 	2125 : GrayLevelNonUniformity [NUMERICAL]
# 	1637 : LargeAreaHighGrayLevelEmphasis [NUMERICAL]
# 	1493 : LowGrayLevelZoneEmphasis [NUMERICAL]
# 	1281 : LargeAreaLowGrayLevelEmphasis [NUMERICAL]
# 	1278 : ZoneEntropy [NUMERICAL]
# 	1116 : SmallAreaLowGrayLevelEmphasis [NUMERICAL]
# 	903 : SmallAreaHighGrayLevelEmphasis [NUMERICAL]
# 	803 : GrayLevelNonUniformityNormalized [NUMERICAL]
# 	773 : GrayLevelVariance [NUMERICAL]
# 	725 : ZoneVariance [NUMERICAL]
# 	697 : SizeZoneNonUniformityNormalized [NUMERICAL]
# 	629 : SmallAreaEmphasis [NUMERICAL]
# 	586 : SizeZoneNonUniformity [NUMERICAL]
# 	573 : LargeAreaEmphasis [NUMERICAL]
# 	487 : ZonePercentage [NUMERICAL]
#
# Condition type in nodes:
# 	346716 : HigherCondition
# Condition type in nodes with depth <= 0:
# 	300 : HigherCondition
# Condition type in nodes with depth <= 1:
# 	900 : HigherCondition
# Condition type in nodes with depth <= 2:
# 	2100 : HigherCondition
# Condition type in nodes with depth <= 3:
# 	4489 : HigherCondition
# Condition type in nodes with depth <= 5:
# 	17252 : HigherCondition
# Node format: NOT_SET
#
# Training OOB:
# 	trees: 1, Out-of-bag evaluation: accuracy:0.807098 logloss:6.95288
# 	trees: 12, Out-of-bag evaluation: accuracy:0.816779 logloss:2.6746
# 	trees: 22, Out-of-bag evaluation: accuracy:0.830348 logloss:1.46297
# 	trees: 32, Out-of-bag evaluation: accuracy:0.835921 logloss:1.09975
# 	trees: 42, Out-of-bag evaluation: accuracy:0.839853 logloss:0.918715
# 	trees: 52, Out-of-bag evaluation: accuracy:0.83931 logloss:0.846571
# 	trees: 62, Out-of-bag evaluation: accuracy:0.840192 logloss:0.758247
# 	trees: 72, Out-of-bag evaluation: accuracy:0.842027 logloss:0.710501
# 	trees: 82, Out-of-bag evaluation: accuracy:0.841921 logloss:0.662729
# 	trees: 92, Out-of-bag evaluation: accuracy:0.842172 logloss:0.623437
# 	trees: 102, Out-of-bag evaluation: accuracy:0.842654 logloss:0.596098
# 	trees: 112, Out-of-bag evaluation: accuracy:0.843422 logloss:0.569578
# 	trees: 122, Out-of-bag evaluation: accuracy:0.842282 logloss:0.554581
# 	trees: 132, Out-of-bag evaluation: accuracy:0.844284 logloss:0.535927
# 	trees: 142, Out-of-bag evaluation: accuracy:0.843272 logloss:0.523491
# 	trees: 152, Out-of-bag evaluation: accuracy:0.843597 logloss:0.517504
# 	trees: 162, Out-of-bag evaluation: accuracy:0.843854 logloss:0.505827
# 	trees: 172, Out-of-bag evaluation: accuracy:0.844443 logloss:0.499625
# 	trees: 182, Out-of-bag evaluation: accuracy:0.844539 logloss:0.48765
# 	trees: 192, Out-of-bag evaluation: accuracy:0.843501 logloss:0.47613
# 	trees: 202, Out-of-bag evaluation: accuracy:0.842864 logloss:0.473266
# 	trees: 212, Out-of-bag evaluation: accuracy:0.842951 logloss:0.467776
# 	trees: 222, Out-of-bag evaluation: accuracy:0.842617 logloss:0.467756
# 	trees: 232, Out-of-bag evaluation: accuracy:0.842407 logloss:0.459377
# 	trees: 242, Out-of-bag evaluation: accuracy:0.843369 logloss:0.449911
# 	trees: 252, Out-of-bag evaluation: accuracy:0.844032 logloss:0.449615
# 	trees: 262, Out-of-bag evaluation: accuracy:0.843484 logloss:0.446566
# 	trees: 272, Out-of-bag evaluation: accuracy:0.843693 logloss:0.446552
# 	trees: 282, Out-of-bag evaluation: accuracy:0.844168 logloss:0.440917
# 	trees: 292, Out-of-bag evaluation: accuracy:0.843498 logloss:0.435368
# 	trees: 300, Out-of-bag evaluation: accuracy:0.843947 logloss:0.43505

# %%
# Model features
model.make_inspector().features()
# Out:
# ["GrayLevelNonUniformity" (1; #0),
#  "GrayLevelNonUniformityNormalized" (1; #1),
#  "GrayLevelVariance" (1; #2),
#  "HighGrayLevelZoneEmphasis" (1; #3),
#  "LargeAreaEmphasis" (1; #4),
#  "LargeAreaHighGrayLevelEmphasis" (1; #5),
#  "LargeAreaLowGrayLevelEmphasis" (1; #6),
#  "LowGrayLevelZoneEmphasis" (1; #7),
#  "SizeZoneNonUniformity" (1; #8),
#  "SizeZoneNonUniformityNormalized" (1; #9),
#  "SmallAreaEmphasis" (1; #10),
#  "SmallAreaHighGrayLevelEmphasis" (1; #11),
#  "SmallAreaLowGrayLevelEmphasis" (1; #12),
#  "ZoneEntropy" (1; #13),
#  "ZonePercentage" (1; #14),
#  "ZoneVariance" (1; #15)]

# %%
# Feature importance
model.make_inspector().variable_importances()
# Out:
# {'INV_MEAN_MIN_DEPTH': [("HighGrayLevelZoneEmphasis" (1; #3),
#    0.20247771567220468),
#   ("GrayLevelNonUniformity" (1; #0), 0.1649610701797855),
#   ("SmallAreaHighGrayLevelEmphasis" (1; #11), 0.13461720074389755),
#   ("LowGrayLevelZoneEmphasis" (1; #7), 0.13203758919352135),
#   ("LargeAreaHighGrayLevelEmphasis" (1; #5), 0.13097037380155185),
#   ("LargeAreaLowGrayLevelEmphasis" (1; #6), 0.11816768934602151),
#   ("SmallAreaLowGrayLevelEmphasis" (1; #12), 0.11734028048943658),
#   ("ZoneEntropy" (1; #13), 0.10757982794769481),
#   ("SizeZoneNonUniformityNormalized" (1; #9), 0.10281702076644277),
#   ("SmallAreaEmphasis" (1; #10), 0.09473481549927598),
#   ("SizeZoneNonUniformity" (1; #8), 0.09267809988946911),
#   ("GrayLevelNonUniformityNormalized" (1; #1), 0.09125949279457121),
#   ("ZoneVariance" (1; #15), 0.0898164491328898),
#   ("GrayLevelVariance" (1; #2), 0.08962545239595403),
#   ("ZonePercentage" (1; #14), 0.08544554841924852),
#   ("LargeAreaEmphasis" (1; #4), 0.08501493744512859)],
#  'SUM_SCORE': [("HighGrayLevelZoneEmphasis" (1; #3), 2392037.0265151714),
#   ("SmallAreaHighGrayLevelEmphasis" (1; #11), 1522859.818237561),
#   ("GrayLevelNonUniformity" (1; #0), 1485736.1163694202),
#   ("LowGrayLevelZoneEmphasis" (1; #7), 1247575.1927467675),
#   ("LargeAreaHighGrayLevelEmphasis" (1; #5), 1049208.5423270178),
#   ("SmallAreaLowGrayLevelEmphasis" (1; #12), 950287.9609721317),
#   ("LargeAreaLowGrayLevelEmphasis" (1; #6), 937509.103338543),
#   ("ZoneEntropy" (1; #13), 797173.8366219439),
#   ("SizeZoneNonUniformityNormalized" (1; #9), 556488.772854613),
#   ("GrayLevelNonUniformityNormalized" (1; #1), 472632.1607004845),
#   ("SmallAreaEmphasis" (1; #10), 456573.7542690808),
#   ("SizeZoneNonUniformity" (1; #8), 448270.1320720749),
#   ("GrayLevelVariance" (1; #2), 446802.9841201256),
#   ("ZoneVariance" (1; #15), 441659.5244426365),
#   ("LargeAreaEmphasis" (1; #4), 336914.6305326262),
#   ("ZonePercentage" (1; #14), 321981.10657707264)],
#  'NUM_AS_ROOT': [("HighGrayLevelZoneEmphasis" (1; #3), 85.0),
#   ("SmallAreaHighGrayLevelEmphasis" (1; #11), 83.0),
#   ("LowGrayLevelZoneEmphasis" (1; #7), 48.0),
#   ("SmallAreaLowGrayLevelEmphasis" (1; #12), 30.0),
#   ("LargeAreaLowGrayLevelEmphasis" (1; #6), 25.0),
#   ("ZoneEntropy" (1; #13), 15.0),
#   ("GrayLevelNonUniformity" (1; #0), 6.0),
#   ("LargeAreaHighGrayLevelEmphasis" (1; #5), 5.0),
#   ("GrayLevelVariance" (1; #2), 2.0),
#   ("GrayLevelNonUniformityNormalized" (1; #1), 1.0)],
#  'NUM_NODES': [("LargeAreaLowGrayLevelEmphasis" (1; #6), 27233.0),
#   ("LargeAreaHighGrayLevelEmphasis" (1; #5), 26891.0),
#   ("GrayLevelNonUniformity" (1; #0), 26839.0),
#   ("HighGrayLevelZoneEmphasis" (1; #3), 24256.0),
#   ("LowGrayLevelZoneEmphasis" (1; #7), 23259.0),
#   ("ZoneEntropy" (1; #13), 22517.0),
#   ("GrayLevelVariance" (1; #2), 21931.0),
#   ("ZoneVariance" (1; #15), 21341.0),
#   ("SmallAreaHighGrayLevelEmphasis" (1; #11), 21147.0),
#   ("GrayLevelNonUniformityNormalized" (1; #1), 21136.0),
#   ("SmallAreaLowGrayLevelEmphasis" (1; #12), 20765.0),
#   ("LargeAreaEmphasis" (1; #4), 18998.0),
#   ("SizeZoneNonUniformity" (1; #8), 18142.0),
#   ("SizeZoneNonUniformityNormalized" (1; #9), 18016.0),
#   ("SmallAreaEmphasis" (1; #10), 17844.0),
#   ("ZonePercentage" (1; #14), 16401.0)]}

# %%
# Model self evaluation
model.make_inspector().evaluation()
# Out:
# Evaluation(num_examples=78712, accuracy=0.8439465366357883, loss=0.43504950901392997, rmse=None, ndcg=None, aucs=None, auuc=None, qini=None)

# %%
logs = model.make_inspector().training_logs()

plt.figure(figsize=(12, 4))
plt.subplot(1, 2, 1)
plt.plot([log.num_trees for log in logs], [log.evaluation.accuracy for log in logs])
plt.xlabel("Number of trees")
plt.ylabel("Accuracy (out-of-bag)")
plt.subplot(1, 2, 2)
plt.plot([log.num_trees for log in logs], [log.evaluation.loss for log in logs])
plt.xlabel("Number of trees")
plt.ylabel("Logloss (out-of-bag)")
plt.show()

# %% [markdown]
# Calculate the score of our hold-out validation dataset

# %%
predictions = model.predict(val_ds)
y_true      = validation_data["label"]

from sklearn.metrics import roc_auc_score
ROC_AUC = roc_auc_score(y_true, predictions)
print("The ROC AUC score is %.5f" % ROC_AUC )
# Out:
# 12/12 [==============================] - 0s 32ms/step
# The ROC AUC score is 0.95679

# %%
# Compute binary classification metrics with sklearn
import numpy as np
from sklearn.metrics import (
    accuracy_score,
    precision_score,
    recall_score,
    f1_score,
    roc_auc_score,
    average_precision_score,
    confusion_matrix,
    classification_report,
    matthews_corrcoef,
    log_loss,
    brier_score_loss,
)

# Get predictions (probabilities or class labels)
preds = model.predict(test_ds)
# If model outputs probabilities, convert to labels by threshold 0.5
if preds.ndim == 2:
    # For TFDF classification, preds may be class probabilities with shape (N, 2)
    if preds.shape[1] == 2:
        pos_probs = preds[:, 1]
    else:
        # If single-probability column (positive class)
        pos_probs = preds[:, -1]
    y_pred = (pos_probs >= 0.5).astype(int)
else:
    # Already class labels
    y_pred = preds.astype(int)
    pos_probs = None

# Ground truth labels (must be 0/1 integers)
y_true = test_data["label"].astype(int).to_numpy()

# Core metrics
metrics = {}
metrics["accuracy"] = accuracy_score(y_true, y_pred)
metrics["precision"] = precision_score(y_true, y_pred, zero_division=0)
metrics["recall"] = recall_score(y_true, y_pred, zero_division=0)
metrics["f1"] = f1_score(y_true, y_pred, zero_division=0)
metrics["mcc"] = matthews_corrcoef(y_true, y_pred)

# Probabilistic metrics (only if we have probabilities)
if pos_probs is not None:
    metrics["roc_auc"] = roc_auc_score(y_true, pos_probs)
    metrics["pr_auc"] = average_precision_score(y_true, pos_probs)
    metrics["log_loss"] = log_loss(y_true, pos_probs, labels=[0,1])
    metrics["brier_score"] = brier_score_loss(y_true, pos_probs)

# Confusion matrix and detailed report
cm = confusion_matrix(y_true, y_pred, labels=[0,1])
report = classification_report(y_true, y_pred, digits=4)

print("Sklearn binary metrics:")
for k, v in metrics.items():
    print(f"{k}: {v:.4f}")
print("\nConfusion matrix:\n", cm)
print("\nClassification report:\n", report)
# Out:
# 23/23 [==============================] - 1s 34ms/step
# Sklearn binary metrics:
# accuracy: 0.9453
# precision: 0.6005
# recall: 0.7723
# f1: 0.6756
# mcc: 0.6524
# roc_auc: 0.9557
# pr_auc: 0.7773
# log_loss: 0.1519
# brier_score: 0.0428
#
# Confusion matrix:
#  [[19977   853]
#  [  378  1282]]
#
# Classification report:
#                precision    recall  f1-score   support
#
#            0     0.9814    0.9590    0.9701     20830
#            1     0.6005    0.7723    0.6756      1660
#
#     accuracy                         0.9453     22490
#    macro avg     0.7909    0.8657    0.8229     22490
# weighted avg     0.9533    0.9453    0.9484     22490
