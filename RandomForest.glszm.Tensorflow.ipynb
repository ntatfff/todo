# %%
# Import packages and modules
import numpy  as np
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow_decision_forests as tfdf

from sklearn.model_selection import train_test_split
# Out:
# 2025-12-19 17:38:43.200401: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-12-19 17:38:43.201548: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:32] Could not find cuda drivers on your machine, GPU will not be used.
# 2025-12-19 17:38:43.206364: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:32] Could not find cuda drivers on your machine, GPU will not be used.
# 2025-12-19 17:38:43.216629: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1766165923.229733   26993 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1766165923.233664   26993 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1766165923.246943   26993 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1766165923.246972   26993 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1766165923.246973   26993 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1766165923.246974   26993 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# 2025-12-19 17:38:43.250680: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# <p style="margin:0px;">🌲 Try <a href="https://ydf.readthedocs.io/en/latest/" target="_blank">YDF</a>, the successor of
#     <a href="https://www.tensorflow.org/decision_forests" target="_blank">TensorFlow
#         Decision Forests</a> using the same algorithms but with more features and faster
#     training!
# </p>
# <div style="display: flex; flex-wrap: wrap; margin:5px;max-width: 880px;">
#     <div style="flex: 1; border-radius: 10px; background-color: F0F0F0; padding: 5px;">
#         <p
#             style="font-weight: bold; margin:0px;text-align: center;border-bottom: 1px solid #C0C0C0;margin-bottom: 4px;">
#             Old code</p>
#         <pre style="overflow-wrap: anywhere; overflow: auto; margin:0px;font-size: 9pt;">
# import tensorflow_decision_forests as tfdf
#
# tf_ds = tfdf.keras.pd_dataframe_to_tf_dataset(ds, label="l")
# model = tfdf.keras.RandomForestModel(label="l")
# model.fit(tf_ds)
# </pre>
#     </div>
#     <div style="width: 5px;"></div>
#     <div style="flex: 1; border-radius: 10px; background-color: F0F0F0; padding: 5px;">
#         <p
#             style="font-weight: bold; margin:0px;text-align: center;border-bottom: 1px solid #C0C0C0;margin-bottom: 4px;">
#             New code</p>
#         <pre style="overflow-wrap: anywhere; overflow: auto; margin:0px;font-size: 9pt;">
# import ydf
#
# model = ydf.RandomForestLearner(label="l").train(ds)
# </pre>
#     </div>
# </div>
# <p style="margin:0px;font-size: 9pt;">(Learn more in the <a
#         href="https://ydf.readthedocs.io/en/latest/tutorial/migrating_to_ydf/" target="_blank">migration
#         guide</a>)</p>

# %%
# Check the version of TensorFlow Decision Forests
print("Found TensorFlow Decision Forests v" + tfdf.__version__)
# Out:
# Found TensorFlow Decision Forests v1.12.0

# %%
# train/validation = 80/20
dataset = pd.read_csv('dataset/glszm/kernel5-radius5/dataset.csv')
train_data, validation_data = train_test_split(
    dataset, test_size=0.2, random_state=42
)

# %%
# Convert the dataset into a TensorFlow dataset.
train_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    train_data, label="label"
)         
val_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    validation_data, label="label"
)
# Out:
# E0000 00:00:1766165925.210961   26993 cuda_executor.cc:1228] INTERNAL: CUDA Runtime error: Failed call to cudaGetRuntimeVersion: Error loading CUDA libraries. GPU will not be used.: Error loading CUDA libraries. GPU will not be used.
# W0000 00:00:1766165925.211423   26993 gpu_device.cc:2341] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...

# %%
import keras

# %%
# %%time

# Train a Random Forest model.
model = tfdf.keras.RandomForestModel()

# Add evaluation metrics
model.compile(
    metrics=["accuracy"]
)
model.fit(x=train_ds)

# # Train a Gradient Boosted Trees model.
# model = tfdf.keras.GradientBoostedTreesModel(num_trees=1500)
# model.fit(train_ds)
# Out:
# Use /tmp/tmpymp_4g3d as temporary training directory
# Reading training dataset...
# Training dataset read in 0:00:02.817651. Found 89956 examples.
# Training model...
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1766165928.172164   26993 kernel.cc:782] Start Yggdrasil model training
# I0000 00:00:1766165928.172215   26993 kernel.cc:783] Collect training examples
# I0000 00:00:1766165928.172224   26993 kernel.cc:795] Dataspec guide:
# column_guides {
#   column_name_pattern: "^__LABEL$"
#   type: CATEGORICAL
#   categorial {
#     min_vocab_frequency: 0
#     max_vocab_count: -1
#   }
# }
# default_column_guide {
#   categorial {
#     max_vocab_count: 2000
#   }
#   discretized_numerical {
#     maximum_num_bins: 255
#   }
# }
# ignore_columns_without_guides: false
# detect_numerical_as_discretized_numerical: false
#
# I0000 00:00:1766165928.172521   26993 kernel.cc:401] Number of batches: 90
# I0000 00:00:1766165928.172543   26993 kernel.cc:402] Number of examples: 89956
# I0000 00:00:1766165928.178299   26993 kernel.cc:802] Training dataset:
# Number of records: 89956
# Number of columns: 17
#
# Number of columns by type:
# 	NUMERICAL: 16 (94.1176%)
# 	CATEGORICAL: 1 (5.88235%)
#
# Columns:
#
# NUMERICAL: 16 (94.1176%)
# 	0: "GrayLevelNonUniformity" NUMERICAL mean:11.5372 min:1 max:29.9039 sd:5.4257
# 	1: "GrayLevelNonUniformityNormalized" NUMERICAL mean:0.0742252 min:0.00804566 max:0.847222 sd:0.0795246
# 	2: "GrayLevelVariance" NUMERICAL mean:109.342 min:0.0763889 max:2145.14 sd:136.237
# 	3: "HighGrayLevelZoneEmphasis" NUMERICAL mean:1612.09 min:1.27273 max:19232.1 sd:1660.08
# 	4: "LargeAreaEmphasis" NUMERICAL mean:7145.02 min:2.11837 max:468012 sd:18070.2
# 	5: "LargeAreaHighGrayLevelEmphasis" NUMERICAL mean:686152 min:1783.92 max:2.36489e+08 sd:2.10776e+06
# 	6: "LargeAreaLowGrayLevelEmphasis" NUMERICAL mean:683.669 min:0.000318269 max:127750 sd:3048.75
# 	7: "LowGrayLevelZoneEmphasis" NUMERICAL mean:0.0170684 min:5.27936e-05 max:0.931818 sd:0.0387012
# 	8: "SizeZoneNonUniformity" NUMERICAL mean:145.415 min:1 max:738.674 sd:125.12
# 	9: "SizeZoneNonUniformityNormalized" NUMERICAL mean:0.332705 min:0.0484694 max:0.745405 sd:0.140914
# 	10: "SmallAreaEmphasis" NUMERICAL mean:0.559192 min:2.68156e-06 max:0.886414 sd:0.176973
# 	11: "SmallAreaHighGrayLevelEmphasis" NUMERICAL mean:1051.37 min:7.51394e-05 max:12444.9 sd:1135.28
# 	12: "SmallAreaLowGrayLevelEmphasis" NUMERICAL mean:0.00497843 min:9.82618e-08 max:0.566962 sd:0.0129378
# 	13: "ZoneEntropy" NUMERICAL mean:6.02682 min:1 max:7.83404 sd:1.12152
# 	14: "ZonePercentage" NUMERICAL mean:0.258223 min:0.00150263 max:0.793388 sd:0.184836
# 	15: "ZoneVariance" NUMERICAL mean:5813.17 min:0.529721 max:212388 sd:14109.9
#
# CATEGORICAL: 1 (5.88235%)
# 	16: "__LABEL" CATEGORICAL integerized vocab-size:3 no-ood-item
#
# Terminology:
# 	nas: Number of non-available (i.e. missing) values.
# 	ood: Out of dictionary.
# 	manually-defined: Attribute whose type is manually defined by the user, i.e., the type was not automatically inferred.
# 	tokenized: The attribute value is obtained through tokenization.
# 	has-dict: The attribute is attached to a string dictionary e.g. a categorical attribute stored as a string.
# 	vocab-size: Number of unique values.
#
# I0000 00:00:1766165928.178394   26993 kernel.cc:818] Configure learner
# I0000 00:00:1766165928.178541   26993 kernel.cc:831] Training config:
# learner: "RANDOM_FOREST"
# features: "^GrayLevelNonUniformity$"
# features: "^GrayLevelNonUniformityNormalized$"
# features: "^GrayLevelVariance$"
# features: "^HighGrayLevelZoneEmphasis$"
# features: "^LargeAreaEmphasis$"
# features: "^LargeAreaHighGrayLevelEmphasis$"
# features: "^LargeAreaLowGrayLevelEmphasis$"
# features: "^LowGrayLevelZoneEmphasis$"
# features: "^SizeZoneNonUniformity$"
# features: "^SizeZoneNonUniformityNormalized$"
# features: "^SmallAreaEmphasis$"
# features: "^SmallAreaHighGrayLevelEmphasis$"
# features: "^SmallAreaLowGrayLevelEmphasis$"
# features: "^ZoneEntropy$"
# features: "^ZonePercentage$"
# features: "^ZoneVariance$"
# label: "^__LABEL$"
# task: CLASSIFICATION
# random_seed: 123456
# metadata {
#   framework: "TF Keras"
# }
# pure_serving_model: false
# [yggdrasil_decision_forests.model.random_forest.proto.random_forest_config] {
#   num_trees: 300
#   decision_tree {
#     max_depth: 16
#     min_examples: 5
#     in_split_min_examples_check: true
#     keep_non_leaf_label_distribution: true
#     num_candidate_attributes: 0
#     missing_value_policy: GLOBAL_IMPUTATION
#     allow_na_conditions: false
#     categorical_set_greedy_forward {
#       sampling: 0.1
#       max_num_items: -1
#       min_item_frequency: 1
#     }
#     growing_strategy_local {
#     }
#     categorical {
#       cart {
#       }
#     }
#     axis_aligned_split {
#     }
#     internal {
#       sorting_strategy: PRESORTED
#     }
#     uplift {
#       min_examples_in_treatment: 5
#       split_score: KULLBACK_LEIBLER
#     }
#     numerical_vector_sequence {
#       max_num_test_examples: 1000
#       num_random_selected_anchors: 100
#     }
#   }
#   winner_take_all_inference: true
#   compute_oob_performances: true
#   compute_oob_variable_importances: false
#   num_oob_variable_importances_permutations: 1
#   bootstrap_training_dataset: true
#   bootstrap_size_ratio: 1
#   adapt_bootstrap_size_ratio_for_maximum_training_duration: false
#   sampling_with_replacement: true
# }
#
# I0000 00:00:1766165928.178895   26993 kernel.cc:834] Deployment config:
# cache_path: "/tmp/tmpymp_4g3d/working_cache"
# num_threads: 12
# try_resume_training: true
#
# I0000 00:00:1766165928.179098   27085 kernel.cc:895] Train model
# I0000 00:00:1766165928.179297   27085 random_forest.cc:438] Training random forest on 89956 example(s) and 16 feature(s).
# I0000 00:00:1766165928.199362   27085 gpu.cc:93] Cannot initialize GPU: Not compiled with GPU support
# I0000 00:00:1766165928.484132   27107 random_forest.cc:865] Train tree 1/300 accuracy:0.94721 logloss:1.90276 [index:10 total:0.28s tree:0.28s]
# I0000 00:00:1766165928.584412   27105 random_forest.cc:865] Train tree 11/300 accuracy:0.955191 logloss:0.882602 [index:8 total:0.38s tree:0.38s]
# I0000 00:00:1766165928.936691   27101 random_forest.cc:865] Train tree 21/300 accuracy:0.957865 logloss:0.60981 [index:20 total:0.73s tree:0.38s]
# I0000 00:00:1766165929.242500   27103 random_forest.cc:865] Train tree 31/300 accuracy:0.958357 logloss:0.505411 [index:31 total:1.04s tree:0.34s]
# I0000 00:00:1766165929.489064   27099 random_forest.cc:865] Train tree 41/300 accuracy:0.959036 logloss:0.447646 [index:41 total:1.29s tree:0.31s]
# I0000 00:00:1766165929.748245   27104 random_forest.cc:865] Train tree 51/300 accuracy:0.959258 logloss:0.410107 [index:48 total:1.55s tree:0.32s]
# I0000 00:00:1766165930.012536   27100 random_forest.cc:865] Train tree 61/300 accuracy:0.959291 logloss:0.37532 [index:58 total:1.81s tree:0.34s]
# I0000 00:00:1766165930.258930   27105 random_forest.cc:865] Train tree 71/300 accuracy:0.959536 logloss:0.347743 [index:70 total:2.06s tree:0.28s]
# I0000 00:00:1766165930.512885   27098 random_forest.cc:865] Train tree 81/300 accuracy:0.959558 logloss:0.32757 [index:80 total:2.31s tree:0.29s]
# I0000 00:00:1766165930.745219   27101 random_forest.cc:865] Train tree 91/300 accuracy:0.959525 logloss:0.313565 [index:91 total:2.54s tree:0.30s]
# I0000 00:00:1766165930.959934   27104 random_forest.cc:865] Train tree 101/300 accuracy:0.959547 logloss:0.295406 [index:99 total:2.76s tree:0.31s]
# I0000 00:00:1766165931.202151   27102 random_forest.cc:865] Train tree 111/300 accuracy:0.959525 logloss:0.284751 [index:111 total:3.00s tree:0.27s]
# I0000 00:00:1766165931.435470   27099 random_forest.cc:865] Train tree 121/300 accuracy:0.959669 logloss:0.275355 [index:120 total:3.23s tree:0.29s]
# I0000 00:00:1766165931.693481   27098 random_forest.cc:865] Train tree 131/300 accuracy:0.960003 logloss:0.265331 [index:130 total:3.49s tree:0.30s]
# I0000 00:00:1766165931.927605   27107 random_forest.cc:865] Train tree 141/300 accuracy:0.959847 logloss:0.259029 [index:140 total:3.72s tree:0.29s]
# I0000 00:00:1766165932.195435   27104 random_forest.cc:865] Train tree 151/300 accuracy:0.959769 logloss:0.254033 [index:150 total:3.99s tree:0.33s]
# I0000 00:00:1766165932.448436   27101 random_forest.cc:865] Train tree 161/300 accuracy:0.959702 logloss:0.244399 [index:160 total:4.25s tree:0.31s]
# I0000 00:00:1766165932.624746   27103 random_forest.cc:865] Train tree 171/300 accuracy:0.959602 logloss:0.238606 [index:171 total:4.42s tree:0.28s]
# I0000 00:00:1766165932.878360   27102 random_forest.cc:865] Train tree 181/300 accuracy:0.959591 logloss:0.234048 [index:180 total:4.68s tree:0.28s]
# I0000 00:00:1766165933.113165   27098 random_forest.cc:865] Train tree 191/300 accuracy:0.959569 logloss:0.229172 [index:190 total:4.91s tree:0.27s]
# I0000 00:00:1766165933.350824   27104 random_forest.cc:865] Train tree 201/300 accuracy:0.959591 logloss:0.227107 [index:200 total:5.15s tree:0.28s]
# I0000 00:00:1766165933.597767   27107 random_forest.cc:865] Train tree 211/300 accuracy:0.959636 logloss:0.223285 [index:209 total:5.39s tree:0.30s]
# I0000 00:00:1766165933.815484   27101 random_forest.cc:865] Train tree 221/300 accuracy:0.959714 logloss:0.220883 [index:220 total:5.61s tree:0.28s]
# I0000 00:00:1766165934.008963   27106 random_forest.cc:865] Train tree 231/300 accuracy:0.959803 logloss:0.216743 [index:230 total:5.81s tree:0.28s]
# I0000 00:00:1766165934.254008   27099 random_forest.cc:865] Train tree 241/300 accuracy:0.959836 logloss:0.212183 [index:240 total:6.05s tree:0.27s]
# I0000 00:00:1766165934.531540   27109 random_forest.cc:865] Train tree 251/300 accuracy:0.959836 logloss:0.206565 [index:253 total:6.33s tree:0.27s]
# I0000 00:00:1766165934.784535   27100 random_forest.cc:865] Train tree 261/300 accuracy:0.959758 logloss:0.203417 [index:259 total:6.58s tree:0.32s]
# I0000 00:00:1766165935.041449   27107 random_forest.cc:865] Train tree 271/300 accuracy:0.95978 logloss:0.201964 [index:270 total:6.84s tree:0.33s]
# I0000 00:00:1766165935.318490   27101 random_forest.cc:865] Train tree 281/300 accuracy:0.959714 logloss:0.199504 [index:280 total:7.12s tree:0.35s]
# I0000 00:00:1766165935.552876   27103 random_forest.cc:865] Train tree 291/300 accuracy:0.959736 logloss:0.197836 [index:290 total:7.35s tree:0.31s]
# I0000 00:00:1766165935.753144   27104 random_forest.cc:865] Train tree 300/300 accuracy:0.959825 logloss:0.196483 [index:299 total:7.55s tree:0.23s]
# I0000 00:00:1766165935.753389   27085 random_forest.cc:949] Final OOB metrics: accuracy:0.959825 logloss:0.196483
# I0000 00:00:1766165935.913993   27085 kernel.cc:926] Export model in log directory: /tmp/tmpymp_4g3d with prefix 297c94eb2be54bdf
# I0000 00:00:1766165936.171834   27085 kernel.cc:944] Save model in resources
# I0000 00:00:1766165936.176117   26993 abstract_model.cc:921] Model self evaluation:
# Number of predictions (without weights): 89956
# Number of predictions (with weights): 89956
# Task: CLASSIFICATION
# Label: __LABEL
#
# Accuracy: 0.959825  CI95[W][0.958731 0.960896]
# LogLoss: : 0.196483
# ErrorRate: : 0.0401752
#
# Default Accuracy: : 0.927787
# Default LogLoss: : 0.259326
# Default ErrorRate: : 0.0722131
#
# Confusion Table:
# truth\prediction
#        1     2
# 1  82856   604
# 2   3010  3486
# Total: 89956
#
#
# 2025-12-19 17:38:56.269842: I tensorflow_decision_forests/tensorflow/ops/inference/kernel.cc:1206] Loading model from path /tmp/tmpymp_4g3d/model/ with prefix 297c94eb2be54bdf
# Model trained in 0:00:09.099178
# Compiling model...
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1766165937.137867   26993 decision_forest.cc:808] Model loaded with 300 root(s), 755338 node(s), and 16 input feature(s).
# I0000 00:00:1766165937.141085   26993 abstract_model.cc:1439] Engine "RandomForestOptPred" built
# 2025-12-19 17:38:57.141130: I tensorflow_decision_forests/tensorflow/ops/inference/kernel.cc:1035] Use fast generic engine
# Model compiled.
# CPU times: user 1min 39s, sys: 1.69 s, total: 1min 41s
# Wall time: 12.6 s

# %%
# Evaluate the model
evaluate = model.evaluate(val_ds, return_dict=True)
print()

for name, value in evaluate.items():
    print(f"{name}: {value:.4f}")
# Out:
# 23/23 [==============================] - 1s 30ms/step - loss: 0.0000e+00 - accuracy: 0.9608
#
# loss: 0.0000
# accuracy: 0.9608

# %%
# Model Summary
model.summary()
# Out:
# Model: "random_forest_model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
# =================================================================
# Total params: 1 (1.00 Byte)
# Trainable params: 0 (0.00 Byte)
# Non-trainable params: 1 (1.00 Byte)
# _________________________________________________________________
# Type: "RANDOM_FOREST"
# Task: CLASSIFICATION
# Label: "__LABEL"
#
# Input Features (16):
# 	GrayLevelNonUniformity
# 	GrayLevelNonUniformityNormalized
# 	GrayLevelVariance
# 	HighGrayLevelZoneEmphasis
# 	LargeAreaEmphasis
# 	LargeAreaHighGrayLevelEmphasis
# 	LargeAreaLowGrayLevelEmphasis
# 	LowGrayLevelZoneEmphasis
# 	SizeZoneNonUniformity
# 	SizeZoneNonUniformityNormalized
# 	SmallAreaEmphasis
# 	SmallAreaHighGrayLevelEmphasis
# 	SmallAreaLowGrayLevelEmphasis
# 	ZoneEntropy
# 	ZonePercentage
# 	ZoneVariance
#
# No weights
#
# Variable Importance: INV_MEAN_MIN_DEPTH:
#     1.        "HighGrayLevelZoneEmphasis"  0.216913 ################
#     2.           "GrayLevelNonUniformity"  0.159313 #########
#     3.         "LowGrayLevelZoneEmphasis"  0.133372 #####
#     4.   "LargeAreaHighGrayLevelEmphasis"  0.132572 #####
#     5.   "SmallAreaHighGrayLevelEmphasis"  0.130262 #####
#     6.    "SmallAreaLowGrayLevelEmphasis"  0.120614 ####
#     7.    "LargeAreaLowGrayLevelEmphasis"  0.118438 ####
#     8.                      "ZoneEntropy"  0.110532 ###
#     9.  "SizeZoneNonUniformityNormalized"  0.100473 #
#    10.                "SmallAreaEmphasis"  0.092267
#    11. "GrayLevelNonUniformityNormalized"  0.091028
#    12.            "SizeZoneNonUniformity"  0.090912
#    13.                     "ZoneVariance"  0.088553
#    14.                "GrayLevelVariance"  0.087282
#    15.                "LargeAreaEmphasis"  0.084290
#    16.                   "ZonePercentage"  0.084205
#
# Variable Importance: NUM_AS_ROOT:
#     1.        "HighGrayLevelZoneEmphasis" 95.000000 ################
#     2.   "SmallAreaHighGrayLevelEmphasis" 68.000000 ###########
#     3.         "LowGrayLevelZoneEmphasis" 49.000000 ########
#     4.    "SmallAreaLowGrayLevelEmphasis" 38.000000 ######
#     5.    "LargeAreaLowGrayLevelEmphasis" 20.000000 ###
#     6.                      "ZoneEntropy" 14.000000 ##
#     7.           "GrayLevelNonUniformity"  6.000000
#     8.   "LargeAreaHighGrayLevelEmphasis"  5.000000
#     9. "GrayLevelNonUniformityNormalized"  4.000000
#    10.                "LargeAreaEmphasis"  1.000000
#
# Variable Importance: NUM_NODES:
#     1.   "LargeAreaHighGrayLevelEmphasis" 30043.000000 ################
#     2.    "LargeAreaLowGrayLevelEmphasis" 29858.000000 ###############
#     3.           "GrayLevelNonUniformity" 28222.000000 #############
#     4.        "HighGrayLevelZoneEmphasis" 26159.000000 ##########
#     5.         "LowGrayLevelZoneEmphasis" 25282.000000 #########
#     6.                      "ZoneEntropy" 24332.000000 ########
#     7.                     "ZoneVariance" 23990.000000 ########
#     8.                "GrayLevelVariance" 23786.000000 #######
#     9. "GrayLevelNonUniformityNormalized" 23056.000000 #######
#    10.   "SmallAreaHighGrayLevelEmphasis" 23020.000000 ######
#    11.    "SmallAreaLowGrayLevelEmphasis" 22487.000000 ######
#    12.                "LargeAreaEmphasis" 21188.000000 ####
#    13.            "SizeZoneNonUniformity" 19525.000000 ##
#    14.  "SizeZoneNonUniformityNormalized" 19488.000000 ##
#    15.                "SmallAreaEmphasis" 19462.000000 ##
#    16.                   "ZonePercentage" 17621.000000
#
# Variable Importance: SUM_SCORE:
#     1.        "HighGrayLevelZoneEmphasis" 1037150.149377 ################
#     2.   "SmallAreaHighGrayLevelEmphasis" 608806.377806 ########
#     3.         "LowGrayLevelZoneEmphasis" 565954.957074 #######
#     4.           "GrayLevelNonUniformity" 493342.665385 ######
#     5.    "SmallAreaLowGrayLevelEmphasis" 435147.203446 #####
#     6.    "LargeAreaLowGrayLevelEmphasis" 387481.684101 ####
#     7.   "LargeAreaHighGrayLevelEmphasis" 381090.647983 ####
#     8.                      "ZoneEntropy" 303300.334842 ###
#     9.                     "ZoneVariance" 194765.846079 #
#    10. "GrayLevelNonUniformityNormalized" 184028.520478 #
#    11.  "SizeZoneNonUniformityNormalized" 182345.026838 #
#    12.                "GrayLevelVariance" 167270.731965
#    13.                "SmallAreaEmphasis" 151933.743992
#    14.            "SizeZoneNonUniformity" 149766.876006
#    15.                "LargeAreaEmphasis" 144169.371551
#    16.                   "ZonePercentage" 122580.099882
#
#
#
# Winner takes all: true
# Out-of-bag evaluation: accuracy:0.959825 logloss:0.196483
# Number of trees: 300
# Total number of nodes: 755338
#
# Number of nodes by tree:
# Count: 300 Average: 2517.79 StdDev: 190.719
# Min: 2009 Max: 2917 Ignored: 0
# ----------------------------------------------
# [ 2009, 2054)  3   1.00%   1.00% #
# [ 2054, 2099)  4   1.33%   2.33% #
# [ 2099, 2145)  4   1.33%   3.67% #
# [ 2145, 2190)  9   3.00%   6.67% ##
# [ 2190, 2236)  8   2.67%   9.33% ##
# [ 2236, 2281) 13   4.33%  13.67% ###
# [ 2281, 2327) 13   4.33%  18.00% ###
# [ 2327, 2372) 12   4.00%  22.00% ###
# [ 2372, 2418) 20   6.67%  28.67% #####
# [ 2418, 2463) 13   4.33%  33.00% ###
# [ 2463, 2508) 24   8.00%  41.00% ######
# [ 2508, 2554) 33  11.00%  52.00% #########
# [ 2554, 2599) 38  12.67%  64.67% ##########
# [ 2599, 2645) 29   9.67%  74.33% ########
# [ 2645, 2690) 22   7.33%  81.67% ######
# [ 2690, 2736) 18   6.00%  87.67% #####
# [ 2736, 2781) 15   5.00%  92.67% ####
# [ 2781, 2827) 10   3.33%  96.00% ###
# [ 2827, 2872)  9   3.00%  99.00% ##
# [ 2872, 2917]  3   1.00% 100.00% #
#
# Depth by leafs:
# Count: 377819 Average: 12.5291 StdDev: 2.26199
# Min: 3 Max: 15 Ignored: 0
# ----------------------------------------------
# [  3,  4)    10   0.00%   0.00%
# [  4,  5)   222   0.06%   0.06%
# [  5,  6)   960   0.25%   0.32%
# [  6,  7)  2679   0.71%   1.02%
# [  7,  8)  6401   1.69%   2.72% #
# [  8,  9) 12050   3.19%   5.91% #
# [  9, 10) 20750   5.49%  11.40% ##
# [ 10, 11) 30423   8.05%  19.45% ###
# [ 11, 12) 40956  10.84%  30.29% ####
# [ 12, 13) 50433  13.35%  43.64% #####
# [ 13, 14) 55833  14.78%  58.42% ######
# [ 14, 15) 58310  15.43%  73.85% ######
# [ 15, 15] 98792  26.15% 100.00% ##########
#
# Number of training obs by leaf:
# Count: 377819 Average: 71.4279 StdDev: 345.784
# Min: 5 Max: 15595 Ignored: 0
# ----------------------------------------------
# [     5,   784) 371714  98.38%  98.38% ##########
# [   784,  1564)   3442   0.91%  99.30%
# [  1564,  2343)   1131   0.30%  99.59%
# [  2343,  3123)    562   0.15%  99.74%
# [  3123,  3902)    287   0.08%  99.82%
# [  3902,  4682)    171   0.05%  99.86%
# [  4682,  5461)    139   0.04%  99.90%
# [  5461,  6241)    108   0.03%  99.93%
# [  6241,  7020)     96   0.03%  99.96%
# [  7020,  7800)     59   0.02%  99.97%
# [  7800,  8580)     43   0.01%  99.98%
# [  8580,  9359)     22   0.01%  99.99%
# [  9359, 10139)     17   0.00%  99.99%
# [ 10139, 10918)     13   0.00% 100.00%
# [ 10918, 11698)      7   0.00% 100.00%
# [ 11698, 12477)      4   0.00% 100.00%
# [ 12477, 13257)      2   0.00% 100.00%
# [ 13257, 14036)      1   0.00% 100.00%
# [ 14036, 14816)      0   0.00% 100.00%
# [ 14816, 15595]      1   0.00% 100.00%
#
# Attribute in nodes:
# 	30043 : LargeAreaHighGrayLevelEmphasis [NUMERICAL]
# 	29858 : LargeAreaLowGrayLevelEmphasis [NUMERICAL]
# 	28222 : GrayLevelNonUniformity [NUMERICAL]
# 	26159 : HighGrayLevelZoneEmphasis [NUMERICAL]
# 	25282 : LowGrayLevelZoneEmphasis [NUMERICAL]
# 	24332 : ZoneEntropy [NUMERICAL]
# 	23990 : ZoneVariance [NUMERICAL]
# 	23786 : GrayLevelVariance [NUMERICAL]
# 	23056 : GrayLevelNonUniformityNormalized [NUMERICAL]
# 	23020 : SmallAreaHighGrayLevelEmphasis [NUMERICAL]
# 	22487 : SmallAreaLowGrayLevelEmphasis [NUMERICAL]
# 	21188 : LargeAreaEmphasis [NUMERICAL]
# 	19525 : SizeZoneNonUniformity [NUMERICAL]
# 	19488 : SizeZoneNonUniformityNormalized [NUMERICAL]
# 	19462 : SmallAreaEmphasis [NUMERICAL]
# 	17621 : ZonePercentage [NUMERICAL]
#
# Attribute in nodes with depth <= 0:
# 	95 : HighGrayLevelZoneEmphasis [NUMERICAL]
# 	68 : SmallAreaHighGrayLevelEmphasis [NUMERICAL]
# 	49 : LowGrayLevelZoneEmphasis [NUMERICAL]
# 	38 : SmallAreaLowGrayLevelEmphasis [NUMERICAL]
# 	20 : LargeAreaLowGrayLevelEmphasis [NUMERICAL]
# 	14 : ZoneEntropy [NUMERICAL]
# 	6 : GrayLevelNonUniformity [NUMERICAL]
# 	5 : LargeAreaHighGrayLevelEmphasis [NUMERICAL]
# 	4 : GrayLevelNonUniformityNormalized [NUMERICAL]
# 	1 : LargeAreaEmphasis [NUMERICAL]
#
# Attribute in nodes with depth <= 1:
# 	208 : HighGrayLevelZoneEmphasis [NUMERICAL]
# 	140 : SmallAreaHighGrayLevelEmphasis [NUMERICAL]
# 	129 : LowGrayLevelZoneEmphasis [NUMERICAL]
# 	95 : SmallAreaLowGrayLevelEmphasis [NUMERICAL]
# 	85 : LargeAreaHighGrayLevelEmphasis [NUMERICAL]
# 	81 : GrayLevelNonUniformity [NUMERICAL]
# 	40 : ZoneEntropy [NUMERICAL]
# 	35 : SizeZoneNonUniformityNormalized [NUMERICAL]
# 	32 : LargeAreaLowGrayLevelEmphasis [NUMERICAL]
# 	18 : SizeZoneNonUniformity [NUMERICAL]
# 	17 : SmallAreaEmphasis [NUMERICAL]
# 	8 : GrayLevelNonUniformityNormalized [NUMERICAL]
# 	4 : GrayLevelVariance [NUMERICAL]
# 	3 : ZoneVariance [NUMERICAL]
# 	3 : ZonePercentage [NUMERICAL]
# 	2 : LargeAreaEmphasis [NUMERICAL]
#
# Attribute in nodes with depth <= 2:
# 	436 : HighGrayLevelZoneEmphasis [NUMERICAL]
# 	290 : LowGrayLevelZoneEmphasis [NUMERICAL]
# 	255 : SmallAreaLowGrayLevelEmphasis [NUMERICAL]
# 	224 : SmallAreaHighGrayLevelEmphasis [NUMERICAL]
# 	218 : LargeAreaHighGrayLevelEmphasis [NUMERICAL]
# 	199 : GrayLevelNonUniformity [NUMERICAL]
# 	122 : ZoneEntropy [NUMERICAL]
# 	121 : LargeAreaLowGrayLevelEmphasis [NUMERICAL]
# 	55 : SizeZoneNonUniformityNormalized [NUMERICAL]
# 	40 : GrayLevelNonUniformityNormalized [NUMERICAL]
# 	34 : SmallAreaEmphasis [NUMERICAL]
# 	34 : SizeZoneNonUniformity [NUMERICAL]
# 	27 : GrayLevelVariance [NUMERICAL]
# 	18 : ZoneVariance [NUMERICAL]
# 	15 : LargeAreaEmphasis [NUMERICAL]
# 	12 : ZonePercentage [NUMERICAL]
#
# Attribute in nodes with depth <= 3:
# 	798 : HighGrayLevelZoneEmphasis [NUMERICAL]
# 	505 : LowGrayLevelZoneEmphasis [NUMERICAL]
# 	504 : GrayLevelNonUniformity [NUMERICAL]
# 	487 : LargeAreaHighGrayLevelEmphasis [NUMERICAL]
# 	419 : SmallAreaLowGrayLevelEmphasis [NUMERICAL]
# 	321 : SmallAreaHighGrayLevelEmphasis [NUMERICAL]
# 	298 : LargeAreaLowGrayLevelEmphasis [NUMERICAL]
# 	297 : ZoneEntropy [NUMERICAL]
# 	150 : GrayLevelNonUniformityNormalized [NUMERICAL]
# 	136 : SizeZoneNonUniformityNormalized [NUMERICAL]
# 	109 : SmallAreaEmphasis [NUMERICAL]
# 	105 : GrayLevelVariance [NUMERICAL]
# 	103 : SizeZoneNonUniformity [NUMERICAL]
# 	99 : ZoneVariance [NUMERICAL]
# 	90 : LargeAreaEmphasis [NUMERICAL]
# 	69 : ZonePercentage [NUMERICAL]
#
# Attribute in nodes with depth <= 5:
# 	2116 : HighGrayLevelZoneEmphasis [NUMERICAL]
# 	1971 : GrayLevelNonUniformity [NUMERICAL]
# 	1692 : LargeAreaHighGrayLevelEmphasis [NUMERICAL]
# 	1490 : LowGrayLevelZoneEmphasis [NUMERICAL]
# 	1394 : LargeAreaLowGrayLevelEmphasis [NUMERICAL]
# 	1210 : ZoneEntropy [NUMERICAL]
# 	1072 : SmallAreaLowGrayLevelEmphasis [NUMERICAL]
# 	947 : SmallAreaHighGrayLevelEmphasis [NUMERICAL]
# 	798 : GrayLevelVariance [NUMERICAL]
# 	780 : ZoneVariance [NUMERICAL]
# 	765 : GrayLevelNonUniformityNormalized [NUMERICAL]
# 	673 : SizeZoneNonUniformityNormalized [NUMERICAL]
# 	614 : SizeZoneNonUniformity [NUMERICAL]
# 	592 : SmallAreaEmphasis [NUMERICAL]
# 	548 : LargeAreaEmphasis [NUMERICAL]
# 	542 : ZonePercentage [NUMERICAL]
#
# Condition type in nodes:
# 	377519 : HigherCondition
# Condition type in nodes with depth <= 0:
# 	300 : HigherCondition
# Condition type in nodes with depth <= 1:
# 	900 : HigherCondition
# Condition type in nodes with depth <= 2:
# 	2100 : HigherCondition
# Condition type in nodes with depth <= 3:
# 	4490 : HigherCondition
# Condition type in nodes with depth <= 5:
# 	17204 : HigherCondition
# Node format: NOT_SET
#
# Training OOB:
# 	trees: 1, Out-of-bag evaluation: accuracy:0.94721 logloss:1.90276
# 	trees: 11, Out-of-bag evaluation: accuracy:0.955191 logloss:0.882602
# 	trees: 21, Out-of-bag evaluation: accuracy:0.957865 logloss:0.60981
# 	trees: 31, Out-of-bag evaluation: accuracy:0.958357 logloss:0.505411
# 	trees: 41, Out-of-bag evaluation: accuracy:0.959036 logloss:0.447646
# 	trees: 51, Out-of-bag evaluation: accuracy:0.959258 logloss:0.410107
# 	trees: 61, Out-of-bag evaluation: accuracy:0.959291 logloss:0.37532
# 	trees: 71, Out-of-bag evaluation: accuracy:0.959536 logloss:0.347743
# 	trees: 81, Out-of-bag evaluation: accuracy:0.959558 logloss:0.32757
# 	trees: 91, Out-of-bag evaluation: accuracy:0.959525 logloss:0.313565
# 	trees: 101, Out-of-bag evaluation: accuracy:0.959547 logloss:0.295406
# 	trees: 111, Out-of-bag evaluation: accuracy:0.959525 logloss:0.284751
# 	trees: 121, Out-of-bag evaluation: accuracy:0.959669 logloss:0.275355
# 	trees: 131, Out-of-bag evaluation: accuracy:0.960003 logloss:0.265331
# 	trees: 141, Out-of-bag evaluation: accuracy:0.959847 logloss:0.259029
# 	trees: 151, Out-of-bag evaluation: accuracy:0.959769 logloss:0.254033
# 	trees: 161, Out-of-bag evaluation: accuracy:0.959702 logloss:0.244399
# 	trees: 171, Out-of-bag evaluation: accuracy:0.959602 logloss:0.238606
# 	trees: 181, Out-of-bag evaluation: accuracy:0.959591 logloss:0.234048
# 	trees: 191, Out-of-bag evaluation: accuracy:0.959569 logloss:0.229172
# 	trees: 201, Out-of-bag evaluation: accuracy:0.959591 logloss:0.227107
# 	trees: 211, Out-of-bag evaluation: accuracy:0.959636 logloss:0.223285
# 	trees: 221, Out-of-bag evaluation: accuracy:0.959714 logloss:0.220883
# 	trees: 231, Out-of-bag evaluation: accuracy:0.959803 logloss:0.216743
# 	trees: 241, Out-of-bag evaluation: accuracy:0.959836 logloss:0.212183
# 	trees: 251, Out-of-bag evaluation: accuracy:0.959836 logloss:0.206565
# 	trees: 261, Out-of-bag evaluation: accuracy:0.959758 logloss:0.203417
# 	trees: 271, Out-of-bag evaluation: accuracy:0.95978 logloss:0.201964
# 	trees: 281, Out-of-bag evaluation: accuracy:0.959714 logloss:0.199504
# 	trees: 291, Out-of-bag evaluation: accuracy:0.959736 logloss:0.197836
# 	trees: 300, Out-of-bag evaluation: accuracy:0.959825 logloss:0.196483

# %%
# Model features
model.make_inspector().features()
# Out:
# ["GrayLevelNonUniformity" (1; #0),
#  "GrayLevelNonUniformityNormalized" (1; #1),
#  "GrayLevelVariance" (1; #2),
#  "HighGrayLevelZoneEmphasis" (1; #3),
#  "LargeAreaEmphasis" (1; #4),
#  "LargeAreaHighGrayLevelEmphasis" (1; #5),
#  "LargeAreaLowGrayLevelEmphasis" (1; #6),
#  "LowGrayLevelZoneEmphasis" (1; #7),
#  "SizeZoneNonUniformity" (1; #8),
#  "SizeZoneNonUniformityNormalized" (1; #9),
#  "SmallAreaEmphasis" (1; #10),
#  "SmallAreaHighGrayLevelEmphasis" (1; #11),
#  "SmallAreaLowGrayLevelEmphasis" (1; #12),
#  "ZoneEntropy" (1; #13),
#  "ZonePercentage" (1; #14),
#  "ZoneVariance" (1; #15)]

# %%
# Feature importance
model.make_inspector().variable_importances()
# Out:
# {'INV_MEAN_MIN_DEPTH': [("HighGrayLevelZoneEmphasis" (1; #3),
#    0.2169127126558889),
#   ("GrayLevelNonUniformity" (1; #0), 0.15931281927145824),
#   ("LowGrayLevelZoneEmphasis" (1; #7), 0.13337245214016788),
#   ("LargeAreaHighGrayLevelEmphasis" (1; #5), 0.1325724515231738),
#   ("SmallAreaHighGrayLevelEmphasis" (1; #11), 0.13026201449990846),
#   ("SmallAreaLowGrayLevelEmphasis" (1; #12), 0.12061395048421221),
#   ("LargeAreaLowGrayLevelEmphasis" (1; #6), 0.11843816718149758),
#   ("ZoneEntropy" (1; #13), 0.1105318229977579),
#   ("SizeZoneNonUniformityNormalized" (1; #9), 0.10047310350976861),
#   ("SmallAreaEmphasis" (1; #10), 0.09226653267003088),
#   ("GrayLevelNonUniformityNormalized" (1; #1), 0.09102819394459934),
#   ("SizeZoneNonUniformity" (1; #8), 0.09091236352519236),
#   ("ZoneVariance" (1; #15), 0.08855265078065182),
#   ("GrayLevelVariance" (1; #2), 0.08728173282844036),
#   ("LargeAreaEmphasis" (1; #4), 0.08429020031179764),
#   ("ZonePercentage" (1; #14), 0.08420509051808513)],
#  'NUM_AS_ROOT': [("HighGrayLevelZoneEmphasis" (1; #3), 95.0),
#   ("SmallAreaHighGrayLevelEmphasis" (1; #11), 68.0),
#   ("LowGrayLevelZoneEmphasis" (1; #7), 49.0),
#   ("SmallAreaLowGrayLevelEmphasis" (1; #12), 38.0),
#   ("LargeAreaLowGrayLevelEmphasis" (1; #6), 20.0),
#   ("ZoneEntropy" (1; #13), 14.0),
#   ("GrayLevelNonUniformity" (1; #0), 6.0),
#   ("LargeAreaHighGrayLevelEmphasis" (1; #5), 5.0),
#   ("GrayLevelNonUniformityNormalized" (1; #1), 4.0),
#   ("LargeAreaEmphasis" (1; #4), 1.0)],
#  'SUM_SCORE': [("HighGrayLevelZoneEmphasis" (1; #3), 1037150.1493774999),
#   ("SmallAreaHighGrayLevelEmphasis" (1; #11), 608806.3778058089),
#   ("LowGrayLevelZoneEmphasis" (1; #7), 565954.9570738918),
#   ("GrayLevelNonUniformity" (1; #0), 493342.6653850356),
#   ("SmallAreaLowGrayLevelEmphasis" (1; #12), 435147.2034462631),
#   ("LargeAreaLowGrayLevelEmphasis" (1; #6), 387481.6841008541),
#   ("LargeAreaHighGrayLevelEmphasis" (1; #5), 381090.64798293426),
#   ("ZoneEntropy" (1; #13), 303300.3348415579),
#   ("ZoneVariance" (1; #15), 194765.84607885496),
#   ("GrayLevelNonUniformityNormalized" (1; #1), 184028.52047757356),
#   ("SizeZoneNonUniformityNormalized" (1; #9), 182345.026838316),
#   ("GrayLevelVariance" (1; #2), 167270.73196482062),
#   ("SmallAreaEmphasis" (1; #10), 151933.74399152797),
#   ("SizeZoneNonUniformity" (1; #8), 149766.87600597294),
#   ("LargeAreaEmphasis" (1; #4), 144169.37155085205),
#   ("ZonePercentage" (1; #14), 122580.09988171748)],
#  'NUM_NODES': [("LargeAreaHighGrayLevelEmphasis" (1; #5), 30043.0),
#   ("LargeAreaLowGrayLevelEmphasis" (1; #6), 29858.0),
#   ("GrayLevelNonUniformity" (1; #0), 28222.0),
#   ("HighGrayLevelZoneEmphasis" (1; #3), 26159.0),
#   ("LowGrayLevelZoneEmphasis" (1; #7), 25282.0),
#   ("ZoneEntropy" (1; #13), 24332.0),
#   ("ZoneVariance" (1; #15), 23990.0),
#   ("GrayLevelVariance" (1; #2), 23786.0),
#   ("GrayLevelNonUniformityNormalized" (1; #1), 23056.0),
#   ("SmallAreaHighGrayLevelEmphasis" (1; #11), 23020.0),
#   ("SmallAreaLowGrayLevelEmphasis" (1; #12), 22487.0),
#   ("LargeAreaEmphasis" (1; #4), 21188.0),
#   ("SizeZoneNonUniformity" (1; #8), 19525.0),
#   ("SizeZoneNonUniformityNormalized" (1; #9), 19488.0),
#   ("SmallAreaEmphasis" (1; #10), 19462.0),
#   ("ZonePercentage" (1; #14), 17621.0)]}

# %%
# Model self evaluation
model.make_inspector().evaluation()
# Out:
# Evaluation(num_examples=89956, accuracy=0.9598248032371381, loss=0.1964834201381148, rmse=None, ndcg=None, aucs=None, auuc=None, qini=None)

# %%
logs = model.make_inspector().training_logs()

plt.figure(figsize=(12, 4))
plt.subplot(1, 2, 1)
plt.plot([log.num_trees for log in logs], [log.evaluation.accuracy for log in logs])
plt.xlabel("Number of trees")
plt.ylabel("Accuracy (out-of-bag)")
plt.subplot(1, 2, 2)
plt.plot([log.num_trees for log in logs], [log.evaluation.loss for log in logs])
plt.xlabel("Number of trees")
plt.ylabel("Logloss (out-of-bag)")
plt.show()

# %% [markdown]
# Calculate the score of our hold-out validation dataset

# %%
predictions = model.predict(val_ds)
y_true      = validation_data["label"]

from sklearn.metrics import roc_auc_score
ROC_AUC = roc_auc_score(y_true, predictions)
print("The ROC AUC score is %.5f" % ROC_AUC )
# Out:
# 23/23 [==============================] - 1s 30ms/step
# The ROC AUC score is 0.95353

# %%
# Compute binary classification metrics with sklearn
import numpy as np
from sklearn.metrics import (
    accuracy_score,
    precision_score,
    recall_score,
    f1_score,
    roc_auc_score,
    average_precision_score,
    confusion_matrix,
    classification_report,
    matthews_corrcoef,
    log_loss,
    brier_score_loss,
)

# Get predictions (probabilities or class labels)
preds = model.predict(val_ds)
# If model outputs probabilities, convert to labels by threshold 0.5
if preds.ndim == 2:
    # For TFDF classification, preds may be class probabilities with shape (N, 2)
    if preds.shape[1] == 2:
        pos_probs = preds[:, 1]
    else:
        # If single-probability column (positive class)
        pos_probs = preds[:, -1]
    y_pred = (pos_probs >= 0.5).astype(int)
else:
    # Already class labels
    y_pred = preds.astype(int)
    pos_probs = None

# Ground truth labels (must be 0/1 integers)
y_true = validation_data["label"].astype(int).to_numpy()

# Core metrics
metrics = {}
metrics["accuracy"] = accuracy_score(y_true, y_pred)
metrics["precision"] = precision_score(y_true, y_pred, zero_division=0)
metrics["recall"] = recall_score(y_true, y_pred, zero_division=0)
metrics["f1"] = f1_score(y_true, y_pred, zero_division=0)
metrics["mcc"] = matthews_corrcoef(y_true, y_pred)

# Probabilistic metrics (only if we have probabilities)
if pos_probs is not None:
    metrics["roc_auc"] = roc_auc_score(y_true, pos_probs)
    metrics["pr_auc"] = average_precision_score(y_true, pos_probs)
    metrics["log_loss"] = log_loss(y_true, pos_probs, labels=[0,1])
    metrics["brier_score"] = brier_score_loss(y_true, pos_probs)

# Confusion matrix and detailed report
cm = confusion_matrix(y_true, y_pred, labels=[0,1])
report = classification_report(y_true, y_pred, digits=4)

print("Sklearn binary metrics:")
for k, v in metrics.items():
    print(f"{k}: {v:.4f}")
print("\nConfusion matrix:\n", cm)
print("\nClassification report:\n", report)
# Out:
# 23/23 [==============================] - 1s 31ms/step
# Sklearn binary metrics:
# accuracy: 0.9608
# precision: 0.8660
# recall: 0.5472
# f1: 0.6706
# mcc: 0.6704
# roc_auc: 0.9535
# pr_auc: 0.7799
# log_loss: 0.1252
# brier_score: 0.0307
#
# Confusion matrix:
#  [[20710   139]
#  [  743   898]]
#
# Classification report:
#                precision    recall  f1-score   support
#
#            0     0.9654    0.9933    0.9791     20849
#            1     0.8660    0.5472    0.6706      1641
#
#     accuracy                         0.9608     22490
#    macro avg     0.9157    0.7703    0.8249     22490
# weighted avg     0.9581    0.9608    0.9566     22490
