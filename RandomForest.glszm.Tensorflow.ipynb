# %%
# Import packages and modules
import numpy  as np
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow_decision_forests as tfdf

from sklearn.model_selection import train_test_split
# Out:
# 2026-05-29 17:24:04.272460: I tensorflow/core/util/port.cc:113] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2026-05-29 17:24:04.312991: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2026-05-29 17:24:04.947927: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
# Check the version of TensorFlow Decision Forests
print("Found TensorFlow Decision Forests v" + tfdf.__version__)
# Out:
# Found TensorFlow Decision Forests v1.9.1

# %%
# train/validation/test = 70/10/20
dataset = pd.read_csv('dataset/glszm/kernel5-radius5/dataset.200p.csv')

train_data, temp_data = train_test_split(
    dataset, test_size=0.3, random_state=42
 )
validation_data, test_data = train_test_split(
    temp_data, test_size=2/3, random_state=42
 )

# %%
from sklearn.utils.class_weight import compute_class_weight

# tinh class weight tren tap train
classes = np.array([0, 1])
weights = compute_class_weight(class_weight="balanced", classes=classes, y=train_data["label"])
class_weight = {0: weights[0], 1: weights[1]}

# gan sample_weight cho tung dong
train_data["sample_weight"] = train_data["label"].map(class_weight)
validation_data["sample_weight"] = validation_data["label"].map(class_weight)
test_data["sample_weight"] = test_data["label"].map(class_weight)

# Convert the dataset into a TensorFlow dataset.
train_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    train_data, label="label", weight="sample_weight"
)         
val_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    validation_data, label="label", weight="sample_weight"
)
test_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    test_data, label="label", weight="sample_weight"
)
# Out:
# 2026-05-29 17:24:08.157497: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:984] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2026-05-29 17:24:08.157840: W tensorflow/core/common_runtime/gpu/gpu_device.cc:2251] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...

# %%
import keras

# %%
# %%time

# Train a Random Forest model.
model = tfdf.keras.RandomForestModel()

# Add evaluation metrics
model.compile(
    metrics=["accuracy"]
)
model.fit(x=train_ds)

# # Train a Gradient Boosted Trees model.
# model = tfdf.keras.GradientBoostedTreesModel(num_trees=1500)
# model.fit(train_ds)
# Out:
# Use /tmp/tmpunws46km as temporary training directory
# Reading training dataset...
# Training dataset read in 0:00:03.155107. Found 157360 examples.
# Training model...
# [INFO 26-05-29 17:24:29.3822 UTC kernel.cc:1233] Loading model from path /tmp/tmpunws46km/model/ with prefix 1c975c4fde8f4312
# Model trained in 0:00:19.478972
# Compiling model...
# [INFO 26-05-29 17:24:30.7673 UTC decision_forest.cc:734] Model loaded with 300 root(s), 1096696 node(s), and 16 input feature(s).
# [INFO 26-05-29 17:24:30.7673 UTC abstract_model.cc:1362] Engine "RandomForestOptPred" built
# [INFO 26-05-29 17:24:30.7673 UTC kernel.cc:1061] Use fast generic engine
# Model compiled.
# CPU times: user 3min 10s, sys: 1.87 s, total: 3min 12s
# Wall time: 25.8 s

# %%
# Evaluate the model
evaluate = model.evaluate(val_ds, return_dict=True)
print()

for name, value in evaluate.items():
    print(f"{name}: {value:.4f}")
# Out:
# WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 23/23 [==============================] - 3s 34ms/step - loss: 0.0000e+00 - accuracy: 0.9167
#
# loss: 0.0000
# accuracy: 0.9167

# %%
# Model Summary
model.summary()
# Out:
# Model: "random_forest_model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
# =================================================================
# Total params: 1 (1.00 Byte)
# Trainable params: 0 (0.00 Byte)
# Non-trainable params: 1 (1.00 Byte)
# _________________________________________________________________
# Type: "RANDOM_FOREST"
# Task: CLASSIFICATION
# Label: "__LABEL"
#
# Input Features (16):
# 	GrayLevelNonUniformity
# 	GrayLevelNonUniformityNormalized
# 	GrayLevelVariance
# 	HighGrayLevelZoneEmphasis
# 	LargeAreaEmphasis
# 	LargeAreaHighGrayLevelEmphasis
# 	LargeAreaLowGrayLevelEmphasis
# 	LowGrayLevelZoneEmphasis
# 	SizeZoneNonUniformity
# 	SizeZoneNonUniformityNormalized
# 	SmallAreaEmphasis
# 	SmallAreaHighGrayLevelEmphasis
# 	SmallAreaLowGrayLevelEmphasis
# 	ZoneEntropy
# 	ZonePercentage
# 	ZoneVariance
#
# Trained with weights
#
# Variable Importance: INV_MEAN_MIN_DEPTH:
#     1.        "HighGrayLevelZoneEmphasis"  0.238803 ################
#     2.           "GrayLevelNonUniformity"  0.140619 #####
#     3.         "LowGrayLevelZoneEmphasis"  0.133582 #####
#     4.   "SmallAreaHighGrayLevelEmphasis"  0.131929 #####
#     5.    "SmallAreaLowGrayLevelEmphasis"  0.128554 ####
#     6.    "LargeAreaLowGrayLevelEmphasis"  0.118399 ###
#     7.   "LargeAreaHighGrayLevelEmphasis"  0.101591 #
#     8.  "SizeZoneNonUniformityNormalized"  0.100867 #
#     9.                "GrayLevelVariance"  0.095234 #
#    10.                "SmallAreaEmphasis"  0.093445 #
#    11.            "SizeZoneNonUniformity"  0.092258
#    12.                      "ZoneEntropy"  0.092215
#    13. "GrayLevelNonUniformityNormalized"  0.089974
#    14.                     "ZoneVariance"  0.088105
#    15.                   "ZonePercentage"  0.084383
#    16.                "LargeAreaEmphasis"  0.082661
#
# Variable Importance: NUM_AS_ROOT:
#     1.        "HighGrayLevelZoneEmphasis" 111.000000 ################
#     2.    "SmallAreaLowGrayLevelEmphasis" 61.000000 ########
#     3.         "LowGrayLevelZoneEmphasis" 44.000000 ######
#     4.   "SmallAreaHighGrayLevelEmphasis" 36.000000 #####
#     5.    "LargeAreaLowGrayLevelEmphasis" 19.000000 ##
#     6.                      "ZoneEntropy" 12.000000 #
#     7. "GrayLevelNonUniformityNormalized"  7.000000
#     8.                "GrayLevelVariance"  6.000000
#     9.   "LargeAreaHighGrayLevelEmphasis"  2.000000
#    10.                "LargeAreaEmphasis"  1.000000
#    11.                     "ZoneVariance"  1.000000
#
# Variable Importance: NUM_NODES:
#     1.    "LargeAreaLowGrayLevelEmphasis" 42771.000000 ################
#     2.   "LargeAreaHighGrayLevelEmphasis" 41851.000000 ###############
#     3.           "GrayLevelNonUniformity" 41614.000000 ##############
#     4.        "HighGrayLevelZoneEmphasis" 36909.000000 ##########
#     5.         "LowGrayLevelZoneEmphasis" 36582.000000 #########
#     6.                     "ZoneVariance" 35889.000000 #########
#     7.                "GrayLevelVariance" 35234.000000 ########
#     8.                      "ZoneEntropy" 34473.000000 #######
#     9.   "SmallAreaHighGrayLevelEmphasis" 33438.000000 ######
#    10.    "SmallAreaLowGrayLevelEmphasis" 32937.000000 ######
#    11. "GrayLevelNonUniformityNormalized" 32823.000000 ######
#    12.                "LargeAreaEmphasis" 31227.000000 ####
#    13.            "SizeZoneNonUniformity" 29195.000000 ##
#    14.  "SizeZoneNonUniformityNormalized" 28653.000000 ##
#    15.                "SmallAreaEmphasis" 28057.000000 #
#    16.                   "ZonePercentage" 26545.000000
#
# Variable Importance: SUM_SCORE:
#     1.        "HighGrayLevelZoneEmphasis" 4570725.919836 ################
#     2.           "GrayLevelNonUniformity" 2626227.653784 #######
#     3.   "SmallAreaHighGrayLevelEmphasis" 2414560.183461 #######
#     4.         "LowGrayLevelZoneEmphasis" 2241872.316236 ######
#     5.    "SmallAreaLowGrayLevelEmphasis" 2164361.256544 ######
#     6.    "LargeAreaLowGrayLevelEmphasis" 1820271.102764 ####
#     7.   "LargeAreaHighGrayLevelEmphasis" 1351201.950592 ##
#     8.  "SizeZoneNonUniformityNormalized" 1223997.110197 ##
#     9.                      "ZoneEntropy" 1100100.008956 #
#    10.                "GrayLevelVariance" 1082061.364467 #
#    11.                "SmallAreaEmphasis" 1071138.037704 #
#    12.            "SizeZoneNonUniformity" 1027774.846971 #
#    13.                     "ZoneVariance" 937398.765332
#    14. "GrayLevelNonUniformityNormalized" 881257.661473
#    15.                   "ZonePercentage" 724443.579795
#    16.                "LargeAreaEmphasis" 716076.500471
#
#
#
# Winner takes all: true
# Out-of-bag evaluation: accuracy:0.83968 logloss:0.472765
# Number of trees: 300
# Total number of nodes: 1096696
#
# Number of nodes by tree:
# Count: 300 Average: 3655.65 StdDev: 219.44
# Min: 2959 Max: 4335 Ignored: 0
# ----------------------------------------------
# [ 2959, 3027)  2   0.67%   0.67%
# [ 3027, 3096)  5   1.67%   2.33% #
# [ 3096, 3165)  4   1.33%   3.67% #
# [ 3165, 3234)  2   0.67%   4.33%
# [ 3234, 3303)  5   1.67%   6.00% #
# [ 3303, 3372) 11   3.67%   9.67% ##
# [ 3372, 3440) 13   4.33%  14.00% ###
# [ 3440, 3509) 23   7.67%  21.67% #####
# [ 3509, 3578) 31  10.33%  32.00% ######
# [ 3578, 3647) 34  11.33%  43.33% #######
# [ 3647, 3716) 48  16.00%  59.33% ##########
# [ 3716, 3785) 43  14.33%  73.67% #########
# [ 3785, 3854) 32  10.67%  84.33% #######
# [ 3854, 3922) 21   7.00%  91.33% ####
# [ 3922, 3991) 13   4.33%  95.67% ###
# [ 3991, 4060)  7   2.33%  98.00% #
# [ 4060, 4129)  1   0.33%  98.33%
# [ 4129, 4198)  3   1.00%  99.33% #
# [ 4198, 4267)  1   0.33%  99.67%
# [ 4267, 4335]  1   0.33% 100.00%
#
# Depth by leafs:
# Count: 548498 Average: 12.8874 StdDev: 2.12593
# Min: 3 Max: 15 Ignored: 0
# ----------------------------------------------
# [  3,  4)      2   0.00%   0.00%
# [  4,  5)     57   0.01%   0.01%
# [  5,  6)    498   0.09%   0.10%
# [  6,  7)   2235   0.41%   0.51%
# [  7,  8)   6229   1.14%   1.64%
# [  8,  9)  13259   2.42%   4.06% #
# [  9, 10)  23686   4.32%   8.38% #
# [ 10, 11)  36925   6.73%  15.11% ##
# [ 11, 12)  52871   9.64%  24.75% ###
# [ 12, 13)  67778  12.36%  37.11% ####
# [ 13, 14)  80003  14.59%  51.69% #####
# [ 14, 15)  88793  16.19%  67.88% #####
# [ 15, 15] 176162  32.12% 100.00% ##########
#
# Number of training obs by leaf:
# Count: 548498 Average: 86.0678 StdDev: 392.397
# Min: 5 Max: 20769 Ignored: 0
# ----------------------------------------------
# [     5,  1043) 541316  98.69%  98.69% ##########
# [  1043,  2081)   3938   0.72%  99.41%
# [  2081,  3119)   1330   0.24%  99.65%
# [  3119,  4158)    739   0.13%  99.79%
# [  4158,  5196)    453   0.08%  99.87%
# [  5196,  6234)    286   0.05%  99.92%
# [  6234,  7272)    171   0.03%  99.95%
# [  7272,  8311)     91   0.02%  99.97%
# [  8311,  9349)     51   0.01%  99.98%
# [  9349, 10387)     46   0.01%  99.99%
# [ 10387, 11425)     29   0.01%  99.99%
# [ 11425, 12464)     17   0.00%  99.99%
# [ 12464, 13502)     10   0.00% 100.00%
# [ 13502, 14540)      5   0.00% 100.00%
# [ 14540, 15578)      7   0.00% 100.00%
# [ 15578, 16617)      5   0.00% 100.00%
# [ 16617, 17655)      2   0.00% 100.00%
# [ 17655, 18693)      1   0.00% 100.00%
# [ 18693, 19731)      0   0.00% 100.00%
# [ 19731, 20769]      1   0.00% 100.00%
#
# Attribute in nodes:
# 	42771 : LargeAreaLowGrayLevelEmphasis [NUMERICAL]
# 	41851 : LargeAreaHighGrayLevelEmphasis [NUMERICAL]
# 	41614 : GrayLevelNonUniformity [NUMERICAL]
# 	36909 : HighGrayLevelZoneEmphasis [NUMERICAL]
# 	36582 : LowGrayLevelZoneEmphasis [NUMERICAL]
# 	35889 : ZoneVariance [NUMERICAL]
# 	35234 : GrayLevelVariance [NUMERICAL]
# 	34473 : ZoneEntropy [NUMERICAL]
# 	33438 : SmallAreaHighGrayLevelEmphasis [NUMERICAL]
# 	32937 : SmallAreaLowGrayLevelEmphasis [NUMERICAL]
# 	32823 : GrayLevelNonUniformityNormalized [NUMERICAL]
# 	31227 : LargeAreaEmphasis [NUMERICAL]
# 	29195 : SizeZoneNonUniformity [NUMERICAL]
# 	28653 : SizeZoneNonUniformityNormalized [NUMERICAL]
# 	28057 : SmallAreaEmphasis [NUMERICAL]
# 	26545 : ZonePercentage [NUMERICAL]
#
# Attribute in nodes with depth <= 0:
# 	111 : HighGrayLevelZoneEmphasis [NUMERICAL]
# 	61 : SmallAreaLowGrayLevelEmphasis [NUMERICAL]
# 	44 : LowGrayLevelZoneEmphasis [NUMERICAL]
# 	36 : SmallAreaHighGrayLevelEmphasis [NUMERICAL]
# 	19 : LargeAreaLowGrayLevelEmphasis [NUMERICAL]
# 	12 : ZoneEntropy [NUMERICAL]
# 	7 : GrayLevelNonUniformityNormalized [NUMERICAL]
# 	6 : GrayLevelVariance [NUMERICAL]
# 	2 : LargeAreaHighGrayLevelEmphasis [NUMERICAL]
# 	1 : ZoneVariance [NUMERICAL]
# 	1 : LargeAreaEmphasis [NUMERICAL]
#
# Attribute in nodes with depth <= 1:
# 	247 : HighGrayLevelZoneEmphasis [NUMERICAL]
# 	138 : SmallAreaLowGrayLevelEmphasis [NUMERICAL]
# 	129 : LowGrayLevelZoneEmphasis [NUMERICAL]
# 	117 : SmallAreaHighGrayLevelEmphasis [NUMERICAL]
# 	66 : GrayLevelNonUniformity [NUMERICAL]
# 	38 : LargeAreaLowGrayLevelEmphasis [NUMERICAL]
# 	34 : LargeAreaHighGrayLevelEmphasis [NUMERICAL]
# 	31 : GrayLevelVariance [NUMERICAL]
# 	23 : SizeZoneNonUniformity [NUMERICAL]
# 	23 : GrayLevelNonUniformityNormalized [NUMERICAL]
# 	18 : ZoneEntropy [NUMERICAL]
# 	14 : SmallAreaEmphasis [NUMERICAL]
# 	12 : SizeZoneNonUniformityNormalized [NUMERICAL]
# 	5 : ZonePercentage [NUMERICAL]
# 	3 : ZoneVariance [NUMERICAL]
# 	2 : LargeAreaEmphasis [NUMERICAL]
#
# Attribute in nodes with depth <= 2:
# 	475 : HighGrayLevelZoneEmphasis [NUMERICAL]
# 	266 : GrayLevelNonUniformity [NUMERICAL]
# 	234 : LowGrayLevelZoneEmphasis [NUMERICAL]
# 	221 : SmallAreaHighGrayLevelEmphasis [NUMERICAL]
# 	210 : SmallAreaLowGrayLevelEmphasis [NUMERICAL]
# 	104 : LargeAreaHighGrayLevelEmphasis [NUMERICAL]
# 	100 : SizeZoneNonUniformityNormalized [NUMERICAL]
# 	98 : GrayLevelVariance [NUMERICAL]
# 	90 : LargeAreaLowGrayLevelEmphasis [NUMERICAL]
# 	85 : SizeZoneNonUniformity [NUMERICAL]
# 	78 : SmallAreaEmphasis [NUMERICAL]
# 	44 : GrayLevelNonUniformityNormalized [NUMERICAL]
# 	39 : ZoneEntropy [NUMERICAL]
# 	34 : ZonePercentage [NUMERICAL]
# 	11 : ZoneVariance [NUMERICAL]
# 	11 : LargeAreaEmphasis [NUMERICAL]
#
# Attribute in nodes with depth <= 3:
# 	929 : HighGrayLevelZoneEmphasis [NUMERICAL]
# 	594 : GrayLevelNonUniformity [NUMERICAL]
# 	425 : LowGrayLevelZoneEmphasis [NUMERICAL]
# 	393 : SmallAreaLowGrayLevelEmphasis [NUMERICAL]
# 	356 : SmallAreaHighGrayLevelEmphasis [NUMERICAL]
# 	286 : LargeAreaLowGrayLevelEmphasis [NUMERICAL]
# 	271 : GrayLevelVariance [NUMERICAL]
# 	251 : LargeAreaHighGrayLevelEmphasis [NUMERICAL]
# 	193 : SizeZoneNonUniformityNormalized [NUMERICAL]
# 	161 : SizeZoneNonUniformity [NUMERICAL]
# 	146 : ZoneEntropy [NUMERICAL]
# 	141 : GrayLevelNonUniformityNormalized [NUMERICAL]
# 	138 : SmallAreaEmphasis [NUMERICAL]
# 	79 : ZonePercentage [NUMERICAL]
# 	78 : ZoneVariance [NUMERICAL]
# 	57 : LargeAreaEmphasis [NUMERICAL]
#
# Attribute in nodes with depth <= 5:
# 	2484 : HighGrayLevelZoneEmphasis [NUMERICAL]
# 	2385 : GrayLevelNonUniformity [NUMERICAL]
# 	1504 : LargeAreaLowGrayLevelEmphasis [NUMERICAL]
# 	1341 : LargeAreaHighGrayLevelEmphasis [NUMERICAL]
# 	1334 : LowGrayLevelZoneEmphasis [NUMERICAL]
# 	1150 : GrayLevelVariance [NUMERICAL]
# 	1029 : SmallAreaHighGrayLevelEmphasis [NUMERICAL]
# 	1023 : SmallAreaLowGrayLevelEmphasis [NUMERICAL]
# 	908 : ZoneEntropy [NUMERICAL]
# 	843 : ZoneVariance [NUMERICAL]
# 	842 : SizeZoneNonUniformity [NUMERICAL]
# 	794 : SizeZoneNonUniformityNormalized [NUMERICAL]
# 	766 : GrayLevelNonUniformityNormalized [NUMERICAL]
# 	617 : SmallAreaEmphasis [NUMERICAL]
# 	600 : ZonePercentage [NUMERICAL]
# 	597 : LargeAreaEmphasis [NUMERICAL]
#
# Condition type in nodes:
# 	548198 : HigherCondition
# Condition type in nodes with depth <= 0:
# 	300 : HigherCondition
# Condition type in nodes with depth <= 1:
# 	900 : HigherCondition
# Condition type in nodes with depth <= 2:
# 	2100 : HigherCondition
# Condition type in nodes with depth <= 3:
# 	4498 : HigherCondition
# Condition type in nodes with depth <= 5:
# 	18217 : HigherCondition
# Node format: NOT_SET
#
# Training OOB:
# 	trees: 1, Out-of-bag evaluation: accuracy:0.797126 logloss:7.31233
# 	trees: 11, Out-of-bag evaluation: accuracy:0.812091 logloss:2.74075
# 	trees: 21, Out-of-bag evaluation: accuracy:0.824525 logloss:1.59389
# 	trees: 31, Out-of-bag evaluation: accuracy:0.829868 logloss:1.21432
# 	trees: 41, Out-of-bag evaluation: accuracy:0.833646 logloss:1.02236
# 	trees: 51, Out-of-bag evaluation: accuracy:0.835552 logloss:0.901104
# 	trees: 61, Out-of-bag evaluation: accuracy:0.83529 logloss:0.822339
# 	trees: 71, Out-of-bag evaluation: accuracy:0.836506 logloss:0.764304
# 	trees: 81, Out-of-bag evaluation: accuracy:0.837061 logloss:0.710122
# 	trees: 91, Out-of-bag evaluation: accuracy:0.83785 logloss:0.669711
# 	trees: 101, Out-of-bag evaluation: accuracy:0.83723 logloss:0.649911
# 	trees: 111, Out-of-bag evaluation: accuracy:0.837624 logloss:0.630282
# 	trees: 121, Out-of-bag evaluation: accuracy:0.838058 logloss:0.61154
# 	trees: 131, Out-of-bag evaluation: accuracy:0.837611 logloss:0.593153
# 	trees: 141, Out-of-bag evaluation: accuracy:0.838706 logloss:0.581615
# 	trees: 151, Out-of-bag evaluation: accuracy:0.838814 logloss:0.569168
# 	trees: 161, Out-of-bag evaluation: accuracy:0.838075 logloss:0.563158
# 	trees: 171, Out-of-bag evaluation: accuracy:0.838754 logloss:0.549276
# 	trees: 181, Out-of-bag evaluation: accuracy:0.838807 logloss:0.543152
# 	trees: 191, Out-of-bag evaluation: accuracy:0.83886 logloss:0.528381
# 	trees: 201, Out-of-bag evaluation: accuracy:0.839136 logloss:0.517839
# 	trees: 211, Out-of-bag evaluation: accuracy:0.839918 logloss:0.509417
# 	trees: 221, Out-of-bag evaluation: accuracy:0.839567 logloss:0.507372
# 	trees: 231, Out-of-bag evaluation: accuracy:0.839864 logloss:0.501117
# 	trees: 241, Out-of-bag evaluation: accuracy:0.839925 logloss:0.49436
# 	trees: 251, Out-of-bag evaluation: accuracy:0.839684 logloss:0.488645
# 	trees: 261, Out-of-bag evaluation: accuracy:0.839322 logloss:0.484811
# 	trees: 271, Out-of-bag evaluation: accuracy:0.839535 logloss:0.479389
# 	trees: 281, Out-of-bag evaluation: accuracy:0.839556 logloss:0.475666
# 	trees: 291, Out-of-bag evaluation: accuracy:0.839448 logloss:0.473317
# 	trees: 300, Out-of-bag evaluation: accuracy:0.83968 logloss:0.472765

# %%
# Model features
model.make_inspector().features()
# Out:
# ["GrayLevelNonUniformity" (1; #0),
#  "GrayLevelNonUniformityNormalized" (1; #1),
#  "GrayLevelVariance" (1; #2),
#  "HighGrayLevelZoneEmphasis" (1; #3),
#  "LargeAreaEmphasis" (1; #4),
#  "LargeAreaHighGrayLevelEmphasis" (1; #5),
#  "LargeAreaLowGrayLevelEmphasis" (1; #6),
#  "LowGrayLevelZoneEmphasis" (1; #7),
#  "SizeZoneNonUniformity" (1; #8),
#  "SizeZoneNonUniformityNormalized" (1; #9),
#  "SmallAreaEmphasis" (1; #10),
#  "SmallAreaHighGrayLevelEmphasis" (1; #11),
#  "SmallAreaLowGrayLevelEmphasis" (1; #12),
#  "ZoneEntropy" (1; #13),
#  "ZonePercentage" (1; #14),
#  "ZoneVariance" (1; #15)]

# %%
# Feature importance
model.make_inspector().variable_importances()
# Out:
# {'INV_MEAN_MIN_DEPTH': [("HighGrayLevelZoneEmphasis" (1; #3),
#    0.23880261797341695),
#   ("GrayLevelNonUniformity" (1; #0), 0.14061855277522375),
#   ("LowGrayLevelZoneEmphasis" (1; #7), 0.13358162459185066),
#   ("SmallAreaHighGrayLevelEmphasis" (1; #11), 0.1319290996623916),
#   ("SmallAreaLowGrayLevelEmphasis" (1; #12), 0.1285535982726624),
#   ("LargeAreaLowGrayLevelEmphasis" (1; #6), 0.11839910541598585),
#   ("LargeAreaHighGrayLevelEmphasis" (1; #5), 0.10159067517465906),
#   ("SizeZoneNonUniformityNormalized" (1; #9), 0.10086734328219445),
#   ("GrayLevelVariance" (1; #2), 0.09523448276652664),
#   ("SmallAreaEmphasis" (1; #10), 0.0934452475361395),
#   ("SizeZoneNonUniformity" (1; #8), 0.09225848672342093),
#   ("ZoneEntropy" (1; #13), 0.09221462589888894),
#   ("GrayLevelNonUniformityNormalized" (1; #1), 0.08997377507744762),
#   ("ZoneVariance" (1; #15), 0.08810453240505269),
#   ("ZonePercentage" (1; #14), 0.08438312016552206),
#   ("LargeAreaEmphasis" (1; #4), 0.08266130000731099)],
#  'SUM_SCORE': [("HighGrayLevelZoneEmphasis" (1; #3), 4570725.91983631),
#   ("GrayLevelNonUniformity" (1; #0), 2626227.6537843975),
#   ("SmallAreaHighGrayLevelEmphasis" (1; #11), 2414560.18346057),
#   ("LowGrayLevelZoneEmphasis" (1; #7), 2241872.316235959),
#   ("SmallAreaLowGrayLevelEmphasis" (1; #12), 2164361.2565442133),
#   ("LargeAreaLowGrayLevelEmphasis" (1; #6), 1820271.102764192),
#   ("LargeAreaHighGrayLevelEmphasis" (1; #5), 1351201.950591522),
#   ("SizeZoneNonUniformityNormalized" (1; #9), 1223997.1101971513),
#   ("ZoneEntropy" (1; #13), 1100100.0089559818),
#   ("GrayLevelVariance" (1; #2), 1082061.364467177),
#   ("SmallAreaEmphasis" (1; #10), 1071138.0377041302),
#   ("SizeZoneNonUniformity" (1; #8), 1027774.8469709276),
#   ("ZoneVariance" (1; #15), 937398.7653321798),
#   ("GrayLevelNonUniformityNormalized" (1; #1), 881257.6614727919),
#   ("ZonePercentage" (1; #14), 724443.5797950198),
#   ("LargeAreaEmphasis" (1; #4), 716076.5004712149)],
#  'NUM_AS_ROOT': [("HighGrayLevelZoneEmphasis" (1; #3), 111.0),
#   ("SmallAreaLowGrayLevelEmphasis" (1; #12), 61.0),
#   ("LowGrayLevelZoneEmphasis" (1; #7), 44.0),
#   ("SmallAreaHighGrayLevelEmphasis" (1; #11), 36.0),
#   ("LargeAreaLowGrayLevelEmphasis" (1; #6), 19.0),
#   ("ZoneEntropy" (1; #13), 12.0),
#   ("GrayLevelNonUniformityNormalized" (1; #1), 7.0),
#   ("GrayLevelVariance" (1; #2), 6.0),
#   ("LargeAreaHighGrayLevelEmphasis" (1; #5), 2.0),
#   ("LargeAreaEmphasis" (1; #4), 1.0),
#   ("ZoneVariance" (1; #15), 1.0)],
#  'NUM_NODES': [("LargeAreaLowGrayLevelEmphasis" (1; #6), 42771.0),
#   ("LargeAreaHighGrayLevelEmphasis" (1; #5), 41851.0),
#   ("GrayLevelNonUniformity" (1; #0), 41614.0),
#   ("HighGrayLevelZoneEmphasis" (1; #3), 36909.0),
#   ("LowGrayLevelZoneEmphasis" (1; #7), 36582.0),
#   ("ZoneVariance" (1; #15), 35889.0),
#   ("GrayLevelVariance" (1; #2), 35234.0),
#   ("ZoneEntropy" (1; #13), 34473.0),
#   ("SmallAreaHighGrayLevelEmphasis" (1; #11), 33438.0),
#   ("SmallAreaLowGrayLevelEmphasis" (1; #12), 32937.0),
#   ("GrayLevelNonUniformityNormalized" (1; #1), 32823.0),
#   ("LargeAreaEmphasis" (1; #4), 31227.0),
#   ("SizeZoneNonUniformity" (1; #8), 29195.0),
#   ("SizeZoneNonUniformityNormalized" (1; #9), 28653.0),
#   ("SmallAreaEmphasis" (1; #10), 28057.0),
#   ("ZonePercentage" (1; #14), 26545.0)]}

# %%
# Model self evaluation
model.make_inspector().evaluation()
# Out:
# Evaluation(num_examples=157360, accuracy=0.8396805040118304, loss=0.47276532898159074, rmse=None, ndcg=None, aucs=None, auuc=None, qini=None)

# %%
logs = model.make_inspector().training_logs()

plt.figure(figsize=(12, 4))
plt.subplot(1, 2, 1)
plt.plot([log.num_trees for log in logs], [log.evaluation.accuracy for log in logs])
plt.xlabel("Number of trees")
plt.ylabel("Accuracy (out-of-bag)")
plt.subplot(1, 2, 2)
plt.plot([log.num_trees for log in logs], [log.evaluation.loss for log in logs])
plt.xlabel("Number of trees")
plt.ylabel("Logloss (out-of-bag)")
plt.show()

# %% [markdown]
# Calculate the score of our hold-out validation dataset

# %%
predictions = model.predict(val_ds)
y_true      = validation_data["label"]

from sklearn.metrics import roc_auc_score
ROC_AUC = roc_auc_score(y_true, predictions)
print("The ROC AUC score is %.5f" % ROC_AUC )
# Out:
# 23/23 [==============================] - 1s 34ms/step
# The ROC AUC score is 0.94105

# %%
# Compute binary classification metrics with sklearn
import numpy as np
from sklearn.metrics import (
    accuracy_score,
    precision_score,
    recall_score,
    f1_score,
    roc_auc_score,
    average_precision_score,
    confusion_matrix,
    classification_report,
    matthews_corrcoef,
    log_loss,
    brier_score_loss,
)

# Get predictions (probabilities or class labels)
preds = model.predict(test_ds)
# If model outputs probabilities, convert to labels by threshold 0.5
if preds.ndim == 2:
    # For TFDF classification, preds may be class probabilities with shape (N, 2)
    if preds.shape[1] == 2:
        pos_probs = preds[:, 1]
    else:
        # If single-probability column (positive class)
        pos_probs = preds[:, -1]
    y_pred = (pos_probs >= 0.5).astype(int)
else:
    # Already class labels
    y_pred = preds.astype(int)
    pos_probs = None

# Ground truth labels (must be 0/1 integers)
y_true = test_data["label"].astype(int).to_numpy()

# Core metrics
metrics = {}
metrics["accuracy"] = accuracy_score(y_true, y_pred)
metrics["precision"] = precision_score(y_true, y_pred, zero_division=0)
metrics["recall"] = recall_score(y_true, y_pred, zero_division=0)
metrics["f1"] = f1_score(y_true, y_pred, zero_division=0)
metrics["mcc"] = matthews_corrcoef(y_true, y_pred)

# Probabilistic metrics (only if we have probabilities)
if pos_probs is not None:
    metrics["roc_auc"] = roc_auc_score(y_true, pos_probs)
    metrics["pr_auc"] = average_precision_score(y_true, pos_probs)
    metrics["log_loss"] = log_loss(y_true, pos_probs, labels=[0,1])
    metrics["brier_score"] = brier_score_loss(y_true, pos_probs)

# Confusion matrix and detailed report
cm = confusion_matrix(y_true, y_pred, labels=[0,1])
report = classification_report(y_true, y_pred, digits=4)

print("Sklearn binary metrics:")
for k, v in metrics.items():
    print(f"{k}: {v:.4f}")
print("\nConfusion matrix:\n", cm)
print("\nClassification report:\n", report)
# Out:
# 45/45 [==============================] - 2s 36ms/step
# Sklearn binary metrics:
# accuracy: 0.9146
# precision: 0.4231
# recall: 0.7674
# f1: 0.5455
# mcc: 0.5299
# roc_auc: 0.9365
# pr_auc: 0.6087
# log_loss: 0.2119
# brier_score: 0.0629
#
# Confusion matrix:
#  [[38820  3140]
#  [  698  2303]]
#
# Classification report:
#                precision    recall  f1-score   support
#
#            0     0.9823    0.9252    0.9529     41960
#            1     0.4231    0.7674    0.5455      3001
#
#     accuracy                         0.9146     44961
#    macro avg     0.7027    0.8463    0.7492     44961
# weighted avg     0.9450    0.9146    0.9257     44961
