# %%
# Import packages and modules
import numpy  as np
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow_decision_forests as tfdf

from sklearn.model_selection import train_test_split
# Out:
# 2026-05-18 18:07:31.193999: I tensorflow/core/util/port.cc:113] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2026-05-18 18:07:31.256801: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2026-05-18 18:07:32.295033: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
# Check the version of TensorFlow Decision Forests
print("Found TensorFlow Decision Forests v" + tfdf.__version__)
# Out:
# Found TensorFlow Decision Forests v1.9.1

# %%
# train/validation/test = 70/10/20
dataset = pd.read_csv('dataset/glszm/kernel5-radius5/dataset.csv')

train_data, temp_data = train_test_split(
    dataset, test_size=0.3, random_state=42
 )
validation_data, test_data = train_test_split(
    temp_data, test_size=2/3, random_state=42
 )

# %%
# Convert the dataset into a TensorFlow dataset.
train_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    train_data, label="label"
)         
val_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    validation_data, label="label"
)
test_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    test_data, label="label"
)
# Out:
# 2026-05-18 18:07:34.599826: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:984] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2026-05-18 18:07:34.600283: W tensorflow/core/common_runtime/gpu/gpu_device.cc:2251] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...

# %%
import keras

# %%
# %%time

# Train a Random Forest model.
model = tfdf.keras.RandomForestModel()

# Add evaluation metrics
model.compile(
    metrics=["accuracy"]
)
model.fit(x=train_ds)

# # Train a Gradient Boosted Trees model.
# model = tfdf.keras.GradientBoostedTreesModel(num_trees=1500)
# model.fit(train_ds)
# Out:
# Use /tmp/tmp1xnbo_u5 as temporary training directory
# Reading training dataset...
# Training dataset read in 0:00:08.640317. Found 78712 examples.
# Training model...
# [INFO 26-05-18 18:08:19.7120 UTC kernel.cc:1233] Loading model from path /tmp/tmp1xnbo_u5/model/ with prefix 545b041d2a2448f5
# [INFO 26-05-18 18:08:21.4222 UTC decision_forest.cc:734] Model loaded with 300 root(s), 689310 node(s), and 16 input feature(s).
# [INFO 26-05-18 18:08:21.4222 UTC abstract_model.cc:1362] Engine "RandomForestOptPred" built
# [INFO 26-05-18 18:08:21.4222 UTC kernel.cc:1061] Use fast generic engine
# Model trained in 0:00:38.127535
# Compiling model...
# Model compiled.
# CPU times: user 1min 45s, sys: 2.68 s, total: 1min 47s
# Wall time: 50.9 s

# %%
# Evaluate the model
evaluate = model.evaluate(val_ds, return_dict=True)
print()

for name, value in evaluate.items():
    print(f"{name}: {value:.4f}")
# Out:
# 12/12 [==============================] - 5s 52ms/step - loss: 0.0000e+00 - accuracy: 0.9610
#
# loss: 0.0000
# accuracy: 0.9610

# %%
# Model Summary
model.summary()
# Out:
# Model: "random_forest_model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
# =================================================================
# Total params: 1 (1.00 Byte)
# Trainable params: 0 (0.00 Byte)
# Non-trainable params: 1 (1.00 Byte)
# _________________________________________________________________
# Type: "RANDOM_FOREST"
# Task: CLASSIFICATION
# Label: "__LABEL"
#
# Input Features (16):
# 	GrayLevelNonUniformity
# 	GrayLevelNonUniformityNormalized
# 	GrayLevelVariance
# 	HighGrayLevelZoneEmphasis
# 	LargeAreaEmphasis
# 	LargeAreaHighGrayLevelEmphasis
# 	LargeAreaLowGrayLevelEmphasis
# 	LowGrayLevelZoneEmphasis
# 	SizeZoneNonUniformity
# 	SizeZoneNonUniformityNormalized
# 	SmallAreaEmphasis
# 	SmallAreaHighGrayLevelEmphasis
# 	SmallAreaLowGrayLevelEmphasis
# 	ZoneEntropy
# 	ZonePercentage
# 	ZoneVariance
#
# No weights
#
# Variable Importance: INV_MEAN_MIN_DEPTH:
#     1.        "HighGrayLevelZoneEmphasis"  0.214682 ################
#     2.           "GrayLevelNonUniformity"  0.163108 #########
#     3.   "SmallAreaHighGrayLevelEmphasis"  0.139446 ######
#     4.   "LargeAreaHighGrayLevelEmphasis"  0.133203 #####
#     5.         "LowGrayLevelZoneEmphasis"  0.131392 #####
#     6.    "LargeAreaLowGrayLevelEmphasis"  0.118918 ####
#     7.    "SmallAreaLowGrayLevelEmphasis"  0.117249 ###
#     8.                      "ZoneEntropy"  0.107727 ##
#     9.  "SizeZoneNonUniformityNormalized"  0.101783 #
#    10.                "SmallAreaEmphasis"  0.094015 #
#    11. "GrayLevelNonUniformityNormalized"  0.090788
#    12.            "SizeZoneNonUniformity"  0.090446
#    13.                     "ZoneVariance"  0.089526
#    14.                "GrayLevelVariance"  0.087670
#    15.                "LargeAreaEmphasis"  0.085903
#    16.                   "ZonePercentage"  0.085810
#
# Variable Importance: NUM_AS_ROOT:
#     1.        "HighGrayLevelZoneEmphasis" 85.000000 ################
#     2.   "SmallAreaHighGrayLevelEmphasis" 83.000000 ###############
#     3.         "LowGrayLevelZoneEmphasis" 48.000000 ########
#     4.    "SmallAreaLowGrayLevelEmphasis" 30.000000 #####
#     5.    "LargeAreaLowGrayLevelEmphasis" 26.000000 ####
#     6.                      "ZoneEntropy" 14.000000 ##
#     7.   "LargeAreaHighGrayLevelEmphasis"  5.000000
#     8.           "GrayLevelNonUniformity"  4.000000
#     9. "GrayLevelNonUniformityNormalized"  3.000000
#    10.                "GrayLevelVariance"  2.000000
#
# Variable Importance: NUM_NODES:
#     1.   "LargeAreaHighGrayLevelEmphasis" 27106.000000 ################
#     2.    "LargeAreaLowGrayLevelEmphasis" 26954.000000 ###############
#     3.           "GrayLevelNonUniformity" 26111.000000 ##############
#     4.        "HighGrayLevelZoneEmphasis" 23582.000000 ##########
#     5.         "LowGrayLevelZoneEmphasis" 22698.000000 #########
#     6.                      "ZoneEntropy" 22290.000000 ########
#     7.                     "ZoneVariance" 21947.000000 ########
#     8.                "GrayLevelVariance" 21636.000000 #######
#     9.   "SmallAreaHighGrayLevelEmphasis" 21047.000000 #######
#    10. "GrayLevelNonUniformityNormalized" 21015.000000 ######
#    11.    "SmallAreaLowGrayLevelEmphasis" 20550.000000 ######
#    12.                "LargeAreaEmphasis" 19581.000000 ####
#    13.  "SizeZoneNonUniformityNormalized" 18150.000000 ##
#    14.            "SizeZoneNonUniformity" 17807.000000 ##
#    15.                "SmallAreaEmphasis" 17699.000000 ##
#    16.                   "ZonePercentage" 16332.000000
#
# Variable Importance: SUM_SCORE:
#     1.        "HighGrayLevelZoneEmphasis" 885326.685694 ################
#     2.   "SmallAreaHighGrayLevelEmphasis" 578105.473645 #########
#     3.         "LowGrayLevelZoneEmphasis" 476809.475847 #######
#     4.           "GrayLevelNonUniformity" 442794.130922 ######
#     5.    "SmallAreaLowGrayLevelEmphasis" 361343.674145 #####
#     6.    "LargeAreaLowGrayLevelEmphasis" 340770.869536 ####
#     7.   "LargeAreaHighGrayLevelEmphasis" 331717.872582 ####
#     8.                      "ZoneEntropy" 259165.012596 ###
#     9.                     "ZoneVariance" 173765.957667 #
#    10.  "SizeZoneNonUniformityNormalized" 164607.970723 #
#    11. "GrayLevelNonUniformityNormalized" 158613.100098
#    12.                "GrayLevelVariance" 148189.967579
#    13.                "SmallAreaEmphasis" 138072.160922
#    14.            "SizeZoneNonUniformity" 130642.157834
#    15.                "LargeAreaEmphasis" 129771.052166
#    16.                   "ZonePercentage" 111472.615744
#
#
#
# Winner takes all: true
# Out-of-bag evaluation: accuracy:0.959409 logloss:0.204267
# Number of trees: 300
# Total number of nodes: 689310
#
# Number of nodes by tree:
# Count: 300 Average: 2297.7 StdDev: 175.31
# Min: 1795 Max: 2681 Ignored: 0
# ----------------------------------------------
# [ 1795, 1839)  2   0.67%   0.67% #
# [ 1839, 1883)  1   0.33%   1.00%
# [ 1883, 1928)  3   1.00%   2.00% #
# [ 1928, 1972)  4   1.33%   3.33% #
# [ 1972, 2016) 11   3.67%   7.00% ###
# [ 2016, 2061) 11   3.67%  10.67% ###
# [ 2061, 2105) 15   5.00%  15.67% ####
# [ 2105, 2149) 12   4.00%  19.67% ###
# [ 2149, 2194) 22   7.33%  27.00% ######
# [ 2194, 2238) 30  10.00%  37.00% ########
# [ 2238, 2282) 24   8.00%  45.00% ######
# [ 2282, 2327) 30  10.00%  55.00% ########
# [ 2327, 2371) 16   5.33%  60.33% ####
# [ 2371, 2415) 40  13.33%  73.67% ##########
# [ 2415, 2460) 18   6.00%  79.67% #####
# [ 2460, 2504) 27   9.00%  88.67% #######
# [ 2504, 2548) 13   4.33%  93.00% ###
# [ 2548, 2593) 11   3.67%  96.67% ###
# [ 2593, 2637)  6   2.00%  98.67% ##
# [ 2637, 2681]  4   1.33% 100.00% #
#
# Depth by leafs:
# Count: 344805 Average: 12.4123 StdDev: 2.30016
# Min: 3 Max: 15 Ignored: 0
# ----------------------------------------------
# [  3,  4)    10   0.00%   0.00%
# [  4,  5)   241   0.07%   0.07%
# [  5,  6)   990   0.29%   0.36%
# [  6,  7)  2836   0.82%   1.18%
# [  7,  8)  6412   1.86%   3.04% #
# [  8,  9) 12089   3.51%   6.55% #
# [  9, 10) 20399   5.92%  12.46% ##
# [ 10, 11) 29811   8.65%  21.11% ####
# [ 11, 12) 38909  11.28%  32.39% #####
# [ 12, 13) 46062  13.36%  45.75% #####
# [ 13, 14) 50767  14.72%  60.48% ######
# [ 14, 15) 51341  14.89%  75.37% ######
# [ 15, 15] 84938  24.63% 100.00% ##########
#
# Number of training obs by leaf:
# Count: 344805 Average: 68.4839 StdDev: 326.084
# Min: 5 Max: 13282 Ignored: 0
# ----------------------------------------------
# [     5,   668) 338320  98.12%  98.12% ##########
# [   668,  1332)   3719   1.08%  99.20%
# [  1332,  1996)   1149   0.33%  99.53%
# [  1996,  2660)    579   0.17%  99.70%
# [  2660,  3324)    308   0.09%  99.79%
# [  3324,  3988)    180   0.05%  99.84%
# [  3988,  4652)    135   0.04%  99.88%
# [  4652,  5316)    103   0.03%  99.91%
# [  5316,  5980)     85   0.02%  99.93%
# [  5980,  6644)     85   0.02%  99.96%
# [  6644,  7307)     45   0.01%  99.97%
# [  7307,  7971)     31   0.01%  99.98%
# [  7971,  8635)     17   0.00%  99.99%
# [  8635,  9299)     21   0.01%  99.99%
# [  9299,  9963)      9   0.00%  99.99%
# [  9963, 10627)      8   0.00% 100.00%
# [ 10627, 11291)      3   0.00% 100.00%
# [ 11291, 11955)      3   0.00% 100.00%
# [ 11955, 12619)      3   0.00% 100.00%
# [ 12619, 13282]      2   0.00% 100.00%
#
# Attribute in nodes:
# 	27106 : LargeAreaHighGrayLevelEmphasis [NUMERICAL]
# 	26954 : LargeAreaLowGrayLevelEmphasis [NUMERICAL]
# 	26111 : GrayLevelNonUniformity [NUMERICAL]
# 	23582 : HighGrayLevelZoneEmphasis [NUMERICAL]
# 	22698 : LowGrayLevelZoneEmphasis [NUMERICAL]
# 	22290 : ZoneEntropy [NUMERICAL]
# 	21947 : ZoneVariance [NUMERICAL]
# 	21636 : GrayLevelVariance [NUMERICAL]
# 	21047 : SmallAreaHighGrayLevelEmphasis [NUMERICAL]
# 	21015 : GrayLevelNonUniformityNormalized [NUMERICAL]
# 	20550 : SmallAreaLowGrayLevelEmphasis [NUMERICAL]
# 	19581 : LargeAreaEmphasis [NUMERICAL]
# 	18150 : SizeZoneNonUniformityNormalized [NUMERICAL]
# 	17807 : SizeZoneNonUniformity [NUMERICAL]
# 	17699 : SmallAreaEmphasis [NUMERICAL]
# 	16332 : ZonePercentage [NUMERICAL]
#
# Attribute in nodes with depth <= 0:
# 	85 : HighGrayLevelZoneEmphasis [NUMERICAL]
# 	83 : SmallAreaHighGrayLevelEmphasis [NUMERICAL]
# 	48 : LowGrayLevelZoneEmphasis [NUMERICAL]
# 	30 : SmallAreaLowGrayLevelEmphasis [NUMERICAL]
# 	26 : LargeAreaLowGrayLevelEmphasis [NUMERICAL]
# 	14 : ZoneEntropy [NUMERICAL]
# 	5 : LargeAreaHighGrayLevelEmphasis [NUMERICAL]
# 	4 : GrayLevelNonUniformity [NUMERICAL]
# 	3 : GrayLevelNonUniformityNormalized [NUMERICAL]
# 	2 : GrayLevelVariance [NUMERICAL]
#
# Attribute in nodes with depth <= 1:
# 	230 : HighGrayLevelZoneEmphasis [NUMERICAL]
# 	133 : SmallAreaHighGrayLevelEmphasis [NUMERICAL]
# 	123 : LowGrayLevelZoneEmphasis [NUMERICAL]
# 	90 : SmallAreaLowGrayLevelEmphasis [NUMERICAL]
# 	84 : GrayLevelNonUniformity [NUMERICAL]
# 	76 : LargeAreaHighGrayLevelEmphasis [NUMERICAL]
# 	36 : LargeAreaLowGrayLevelEmphasis [NUMERICAL]
# 	35 : SizeZoneNonUniformityNormalized [NUMERICAL]
# 	32 : ZoneEntropy [NUMERICAL]
# 	22 : SmallAreaEmphasis [NUMERICAL]
# 	10 : ZonePercentage [NUMERICAL]
# 	10 : SizeZoneNonUniformity [NUMERICAL]
# 	7 : GrayLevelVariance [NUMERICAL]
# 	6 : LargeAreaEmphasis [NUMERICAL]
# 	6 : GrayLevelNonUniformityNormalized [NUMERICAL]
#
# Attribute in nodes with depth <= 2:
# 	429 : HighGrayLevelZoneEmphasis [NUMERICAL]
# 	286 : LowGrayLevelZoneEmphasis [NUMERICAL]
# 	236 : SmallAreaLowGrayLevelEmphasis [NUMERICAL]
# 	233 : GrayLevelNonUniformity [NUMERICAL]
# 	222 : LargeAreaHighGrayLevelEmphasis [NUMERICAL]
# 	216 : SmallAreaHighGrayLevelEmphasis [NUMERICAL]
# 	132 : ZoneEntropy [NUMERICAL]
# 	104 : LargeAreaLowGrayLevelEmphasis [NUMERICAL]
# 	62 : SizeZoneNonUniformityNormalized [NUMERICAL]
# 	39 : SmallAreaEmphasis [NUMERICAL]
# 	37 : GrayLevelNonUniformityNormalized [NUMERICAL]
# 	32 : GrayLevelVariance [NUMERICAL]
# 	24 : SizeZoneNonUniformity [NUMERICAL]
# 	20 : ZonePercentage [NUMERICAL]
# 	18 : LargeAreaEmphasis [NUMERICAL]
# 	10 : ZoneVariance [NUMERICAL]
#
# Attribute in nodes with depth <= 3:
# 	779 : HighGrayLevelZoneEmphasis [NUMERICAL]
# 	544 : GrayLevelNonUniformity [NUMERICAL]
# 	512 : LowGrayLevelZoneEmphasis [NUMERICAL]
# 	508 : LargeAreaHighGrayLevelEmphasis [NUMERICAL]
# 	411 : SmallAreaLowGrayLevelEmphasis [NUMERICAL]
# 	322 : SmallAreaHighGrayLevelEmphasis [NUMERICAL]
# 	284 : ZoneEntropy [NUMERICAL]
# 	280 : LargeAreaLowGrayLevelEmphasis [NUMERICAL]
# 	144 : SizeZoneNonUniformityNormalized [NUMERICAL]
# 	132 : GrayLevelNonUniformityNormalized [NUMERICAL]
# 	104 : GrayLevelVariance [NUMERICAL]
# 	103 : SizeZoneNonUniformity [NUMERICAL]
# 	101 : LargeAreaEmphasis [NUMERICAL]
# 	97 : SmallAreaEmphasis [NUMERICAL]
# 	92 : ZoneVariance [NUMERICAL]
# 	77 : ZonePercentage [NUMERICAL]
#
# Attribute in nodes with depth <= 5:
# 	2033 : HighGrayLevelZoneEmphasis [NUMERICAL]
# 	1997 : GrayLevelNonUniformity [NUMERICAL]
# 	1762 : LargeAreaHighGrayLevelEmphasis [NUMERICAL]
# 	1452 : LowGrayLevelZoneEmphasis [NUMERICAL]
# 	1329 : LargeAreaLowGrayLevelEmphasis [NUMERICAL]
# 	1145 : SmallAreaLowGrayLevelEmphasis [NUMERICAL]
# 	1143 : ZoneEntropy [NUMERICAL]
# 	903 : SmallAreaHighGrayLevelEmphasis [NUMERICAL]
# 	772 : ZoneVariance [NUMERICAL]
# 	769 : GrayLevelVariance [NUMERICAL]
# 	744 : GrayLevelNonUniformityNormalized [NUMERICAL]
# 	677 : SizeZoneNonUniformityNormalized [NUMERICAL]
# 	644 : SizeZoneNonUniformity [NUMERICAL]
# 	621 : SmallAreaEmphasis [NUMERICAL]
# 	620 : LargeAreaEmphasis [NUMERICAL]
# 	506 : ZonePercentage [NUMERICAL]
#
# Condition type in nodes:
# 	344505 : HigherCondition
# Condition type in nodes with depth <= 0:
# 	300 : HigherCondition
# Condition type in nodes with depth <= 1:
# 	900 : HigherCondition
# Condition type in nodes with depth <= 2:
# 	2100 : HigherCondition
# Condition type in nodes with depth <= 3:
# 	4490 : HigherCondition
# Condition type in nodes with depth <= 5:
# 	17117 : HigherCondition
# Node format: NOT_SET
#
# Training OOB:
# 	trees: 1, Out-of-bag evaluation: accuracy:0.943599 logloss:2.0329
# 	trees: 11, Out-of-bag evaluation: accuracy:0.954301 logloss:0.937262
# 	trees: 21, Out-of-bag evaluation: accuracy:0.957181 logloss:0.625207
# 	trees: 32, Out-of-bag evaluation: accuracy:0.957986 logloss:0.523457
# 	trees: 43, Out-of-bag evaluation: accuracy:0.958558 logloss:0.443025
# 	trees: 53, Out-of-bag evaluation: accuracy:0.958939 logloss:0.402611
# 	trees: 63, Out-of-bag evaluation: accuracy:0.958977 logloss:0.379425
# 	trees: 73, Out-of-bag evaluation: accuracy:0.959066 logloss:0.357461
# 	trees: 83, Out-of-bag evaluation: accuracy:0.959015 logloss:0.338509
# 	trees: 94, Out-of-bag evaluation: accuracy:0.959028 logloss:0.322133
# 	trees: 104, Out-of-bag evaluation: accuracy:0.958863 logloss:0.306878
# 	trees: 114, Out-of-bag evaluation: accuracy:0.958914 logloss:0.293828
# 	trees: 124, Out-of-bag evaluation: accuracy:0.958863 logloss:0.282387
# 	trees: 134, Out-of-bag evaluation: accuracy:0.958799 logloss:0.270983
# 	trees: 144, Out-of-bag evaluation: accuracy:0.958837 logloss:0.264934
# 	trees: 154, Out-of-bag evaluation: accuracy:0.958977 logloss:0.260487
# 	trees: 164, Out-of-bag evaluation: accuracy:0.959053 logloss:0.252393
# 	trees: 174, Out-of-bag evaluation: accuracy:0.959053 logloss:0.249235
# 	trees: 184, Out-of-bag evaluation: accuracy:0.95913 logloss:0.243919
# 	trees: 194, Out-of-bag evaluation: accuracy:0.959295 logloss:0.236981
# 	trees: 204, Out-of-bag evaluation: accuracy:0.959269 logloss:0.233361
# 	trees: 214, Out-of-bag evaluation: accuracy:0.95918 logloss:0.229396
# 	trees: 224, Out-of-bag evaluation: accuracy:0.959168 logloss:0.226948
# 	trees: 234, Out-of-bag evaluation: accuracy:0.95913 logloss:0.222613
# 	trees: 244, Out-of-bag evaluation: accuracy:0.959104 logloss:0.218164
# 	trees: 254, Out-of-bag evaluation: accuracy:0.95913 logloss:0.214677
# 	trees: 264, Out-of-bag evaluation: accuracy:0.959282 logloss:0.213047
# 	trees: 274, Out-of-bag evaluation: accuracy:0.959244 logloss:0.210632
# 	trees: 284, Out-of-bag evaluation: accuracy:0.959358 logloss:0.208676
# 	trees: 294, Out-of-bag evaluation: accuracy:0.959384 logloss:0.205469
# 	trees: 300, Out-of-bag evaluation: accuracy:0.959409 logloss:0.204267

# %%
# Model features
model.make_inspector().features()
# Out:
# ["GrayLevelNonUniformity" (1; #0),
#  "GrayLevelNonUniformityNormalized" (1; #1),
#  "GrayLevelVariance" (1; #2),
#  "HighGrayLevelZoneEmphasis" (1; #3),
#  "LargeAreaEmphasis" (1; #4),
#  "LargeAreaHighGrayLevelEmphasis" (1; #5),
#  "LargeAreaLowGrayLevelEmphasis" (1; #6),
#  "LowGrayLevelZoneEmphasis" (1; #7),
#  "SizeZoneNonUniformity" (1; #8),
#  "SizeZoneNonUniformityNormalized" (1; #9),
#  "SmallAreaEmphasis" (1; #10),
#  "SmallAreaHighGrayLevelEmphasis" (1; #11),
#  "SmallAreaLowGrayLevelEmphasis" (1; #12),
#  "ZoneEntropy" (1; #13),
#  "ZonePercentage" (1; #14),
#  "ZoneVariance" (1; #15)]

# %%
# Feature importance
model.make_inspector().variable_importances()
# Out:
# {'INV_MEAN_MIN_DEPTH': [("HighGrayLevelZoneEmphasis" (1; #3),
#    0.21468214598712437),
#   ("GrayLevelNonUniformity" (1; #0), 0.1631075530763605),
#   ("SmallAreaHighGrayLevelEmphasis" (1; #11), 0.13944620038698335),
#   ("LargeAreaHighGrayLevelEmphasis" (1; #5), 0.13320284189023127),
#   ("LowGrayLevelZoneEmphasis" (1; #7), 0.13139168731985001),
#   ("LargeAreaLowGrayLevelEmphasis" (1; #6), 0.11891752131083945),
#   ("SmallAreaLowGrayLevelEmphasis" (1; #12), 0.1172485801690973),
#   ("ZoneEntropy" (1; #13), 0.10772658287232988),
#   ("SizeZoneNonUniformityNormalized" (1; #9), 0.10178320347674026),
#   ("SmallAreaEmphasis" (1; #10), 0.09401538959064036),
#   ("GrayLevelNonUniformityNormalized" (1; #1), 0.09078783371279699),
#   ("SizeZoneNonUniformity" (1; #8), 0.0904464812423182),
#   ("ZoneVariance" (1; #15), 0.08952566931464677),
#   ("GrayLevelVariance" (1; #2), 0.08767046188889738),
#   ("LargeAreaEmphasis" (1; #4), 0.0859027021163993),
#   ("ZonePercentage" (1; #14), 0.08580957498022095)],
#  'SUM_SCORE': [("HighGrayLevelZoneEmphasis" (1; #3), 885326.6856936304),
#   ("SmallAreaHighGrayLevelEmphasis" (1; #11), 578105.4736445448),
#   ("LowGrayLevelZoneEmphasis" (1; #7), 476809.4758465723),
#   ("GrayLevelNonUniformity" (1; #0), 442794.1309220483),
#   ("SmallAreaLowGrayLevelEmphasis" (1; #12), 361343.6741449949),
#   ("LargeAreaLowGrayLevelEmphasis" (1; #6), 340770.86953602056),
#   ("LargeAreaHighGrayLevelEmphasis" (1; #5), 331717.8725822767),
#   ("ZoneEntropy" (1; #13), 259165.01259639923),
#   ("ZoneVariance" (1; #15), 173765.957667078),
#   ("SizeZoneNonUniformityNormalized" (1; #9), 164607.97072277375),
#   ("GrayLevelNonUniformityNormalized" (1; #1), 158613.10009784347),
#   ("GrayLevelVariance" (1; #2), 148189.96757904714),
#   ("SmallAreaEmphasis" (1; #10), 138072.16092187935),
#   ("SizeZoneNonUniformity" (1; #8), 130642.15783436),
#   ("LargeAreaEmphasis" (1; #4), 129771.05216554052),
#   ("ZonePercentage" (1; #14), 111472.61574439528)],
#  'NUM_AS_ROOT': [("HighGrayLevelZoneEmphasis" (1; #3), 85.0),
#   ("SmallAreaHighGrayLevelEmphasis" (1; #11), 83.0),
#   ("LowGrayLevelZoneEmphasis" (1; #7), 48.0),
#   ("SmallAreaLowGrayLevelEmphasis" (1; #12), 30.0),
#   ("LargeAreaLowGrayLevelEmphasis" (1; #6), 26.0),
#   ("ZoneEntropy" (1; #13), 14.0),
#   ("LargeAreaHighGrayLevelEmphasis" (1; #5), 5.0),
#   ("GrayLevelNonUniformity" (1; #0), 4.0),
#   ("GrayLevelNonUniformityNormalized" (1; #1), 3.0),
#   ("GrayLevelVariance" (1; #2), 2.0)],
#  'NUM_NODES': [("LargeAreaHighGrayLevelEmphasis" (1; #5), 27106.0),
#   ("LargeAreaLowGrayLevelEmphasis" (1; #6), 26954.0),
#   ("GrayLevelNonUniformity" (1; #0), 26111.0),
#   ("HighGrayLevelZoneEmphasis" (1; #3), 23582.0),
#   ("LowGrayLevelZoneEmphasis" (1; #7), 22698.0),
#   ("ZoneEntropy" (1; #13), 22290.0),
#   ("ZoneVariance" (1; #15), 21947.0),
#   ("GrayLevelVariance" (1; #2), 21636.0),
#   ("SmallAreaHighGrayLevelEmphasis" (1; #11), 21047.0),
#   ("GrayLevelNonUniformityNormalized" (1; #1), 21015.0),
#   ("SmallAreaLowGrayLevelEmphasis" (1; #12), 20550.0),
#   ("LargeAreaEmphasis" (1; #4), 19581.0),
#   ("SizeZoneNonUniformityNormalized" (1; #9), 18150.0),
#   ("SizeZoneNonUniformity" (1; #8), 17807.0),
#   ("SmallAreaEmphasis" (1; #10), 17699.0),
#   ("ZonePercentage" (1; #14), 16332.0)]}

# %%
# Model self evaluation
model.make_inspector().evaluation()
# Out:
# Evaluation(num_examples=78712, accuracy=0.9594089846529119, loss=0.20426692736224422, rmse=None, ndcg=None, aucs=None, auuc=None, qini=None)

# %%
logs = model.make_inspector().training_logs()

plt.figure(figsize=(12, 4))
plt.subplot(1, 2, 1)
plt.plot([log.num_trees for log in logs], [log.evaluation.accuracy for log in logs])
plt.xlabel("Number of trees")
plt.ylabel("Accuracy (out-of-bag)")
plt.subplot(1, 2, 2)
plt.plot([log.num_trees for log in logs], [log.evaluation.loss for log in logs])
plt.xlabel("Number of trees")
plt.ylabel("Logloss (out-of-bag)")
plt.show()

# %% [markdown]
# Calculate the score of our hold-out validation dataset

# %%
predictions = model.predict(val_ds)
y_true      = validation_data["label"]

from sklearn.metrics import roc_auc_score
ROC_AUC = roc_auc_score(y_true, predictions)
print("The ROC AUC score is %.5f" % ROC_AUC )
# Out:
# 12/12 [==============================] - 1s 49ms/step
# The ROC AUC score is 0.95391

# %%
# Compute binary classification metrics with sklearn
import numpy as np
from sklearn.metrics import (
    accuracy_score,
    precision_score,
    recall_score,
    f1_score,
    roc_auc_score,
    average_precision_score,
    confusion_matrix,
    classification_report,
    matthews_corrcoef,
    log_loss,
    brier_score_loss,
)

# Get predictions (probabilities or class labels)
preds = model.predict(test_ds)
# If model outputs probabilities, convert to labels by threshold 0.5
if preds.ndim == 2:
    # For TFDF classification, preds may be class probabilities with shape (N, 2)
    if preds.shape[1] == 2:
        pos_probs = preds[:, 1]
    else:
        # If single-probability column (positive class)
        pos_probs = preds[:, -1]
    y_pred = (pos_probs >= 0.5).astype(int)
else:
    # Already class labels
    y_pred = preds.astype(int)
    pos_probs = None

# Ground truth labels (must be 0/1 integers)
y_true = test_data["label"].astype(int).to_numpy()

# Core metrics
metrics = {}
metrics["accuracy"] = accuracy_score(y_true, y_pred)
metrics["precision"] = precision_score(y_true, y_pred, zero_division=0)
metrics["recall"] = recall_score(y_true, y_pred, zero_division=0)
metrics["f1"] = f1_score(y_true, y_pred, zero_division=0)
metrics["mcc"] = matthews_corrcoef(y_true, y_pred)

# Probabilistic metrics (only if we have probabilities)
if pos_probs is not None:
    metrics["roc_auc"] = roc_auc_score(y_true, pos_probs)
    metrics["pr_auc"] = average_precision_score(y_true, pos_probs)
    metrics["log_loss"] = log_loss(y_true, pos_probs, labels=[0,1])
    metrics["brier_score"] = brier_score_loss(y_true, pos_probs)

# Confusion matrix and detailed report
cm = confusion_matrix(y_true, y_pred, labels=[0,1])
report = classification_report(y_true, y_pred, digits=4)

print("Sklearn binary metrics:")
for k, v in metrics.items():
    print(f"{k}: {v:.4f}")
print("\nConfusion matrix:\n", cm)
print("\nClassification report:\n", report)
# Out:
# 23/23 [==============================] - 1s 50ms/step
# Sklearn binary metrics:
# accuracy: 0.9607
# precision: 0.8660
# recall: 0.5530
# f1: 0.6750
# mcc: 0.6739
# roc_auc: 0.9539
# pr_auc: 0.7811
# log_loss: 0.1236
# brier_score: 0.0308
#
# Confusion matrix:
#  [[20688   142]
#  [  742   918]]
#
# Classification report:
#                precision    recall  f1-score   support
#
#            0     0.9654    0.9932    0.9791     20830
#            1     0.8660    0.5530    0.6750      1660
#
#     accuracy                         0.9607     22490
#    macro avg     0.9157    0.7731    0.8270     22490
# weighted avg     0.9580    0.9607    0.9566     22490
