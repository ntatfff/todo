# %% [markdown]
# <a href="https://colab.research.google.com/github/ntatfff/todo/blob/202411241258/ColabRadiomicsFeatureExtractor.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
kernel = 1
className = 'firstorder'

# %%
# Parameters
kernel = 3
className = "glcm"

# %%
import radiomics
import numpy as np
import SimpleITK as sitk
import radiomics.featureextractor
import os
import six
from os import path
import pandas as pd

def featureExtractor(fileId):
  imagePath = './dataset/BraTS2021_Training_Data/%s/%s_flair.nii.gz' % (fileId, fileId)
  image = sitk.ReadImage(imagePath)
  maskPath ='./dataset/BraTS2021_Training_Data/%s/%s_kernel%s_non_tumor.nii.gz' % (fileId, fileId, kernel)
  mask = sitk.ReadImage(maskPath)

  settings = {}
  settings['kernelRadius'] = kernel
  settings['maskedKernel'] = False
  settings['voxelBatch'] = 1000
  extractor = radiomics.featureextractor.RadiomicsFeatureExtractor(**settings)
  extractor.disableAllFeatures()
  extractor.enableFeatureClassByName(className)

  featureMap = extractor.execute(image, mask, voxelBased=True)

  for featureName, featureValue in six.iteritems(featureMap):
    if isinstance(featureValue, sitk.Image):
      fileFolder = './dataset/%s/kernel%s/non_tumor/%s' % (className, kernel, fileId)
      if path.exists(fileFolder) == False:
        os.makedirs(fileFolder, exist_ok=True)
      sitk.WriteImage(featureValue, '%s/%s.nrrd' % (fileFolder, featureName))
      print('Computed %s, stored as "%s/%s.nrrd"' % (featureName, fileFolder, featureName))
    # else:
    #   print('%s: %s' % (featureName, featureValue))

monitorFilePath = './dataset/%s/kernel%s/non_tumor.monitor.csv' % (className, kernel)
monitor = pd.read_csv(monitorFilePath, index_col='no')
for i, row in monitor.iterrows():
  if row['done'] != 0:
    continue
  fileId = row['file']
  print('Starting %s' % (fileId))
  featureExtractor(fileId)
  monitor.at[i, 'done'] = 1
  monitor.to_csv(monitorFilePath)
# Out:
# Starting BraTS2021_00002
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# Computed original_glcm_Autocorrelation, stored as "./dataset/glcm/kernel3/non_tumor/BraTS2021_00002/original_glcm_Autocorrelation.nrrd"
# Computed original_glcm_ClusterProminence, stored as "./dataset/glcm/kernel3/non_tumor/BraTS2021_00002/original_glcm_ClusterProminence.nrrd"
# Computed original_glcm_ClusterShade, stored as "./dataset/glcm/kernel3/non_tumor/BraTS2021_00002/original_glcm_ClusterShade.nrrd"
# Computed original_glcm_ClusterTendency, stored as "./dataset/glcm/kernel3/non_tumor/BraTS2021_00002/original_glcm_ClusterTendency.nrrd"
# Computed original_glcm_Contrast, stored as "./dataset/glcm/kernel3/non_tumor/BraTS2021_00002/original_glcm_Contrast.nrrd"
# Computed original_glcm_Correlation, stored as "./dataset/glcm/kernel3/non_tumor/BraTS2021_00002/original_glcm_Correlation.nrrd"
# Computed original_glcm_DifferenceAverage, stored as "./dataset/glcm/kernel3/non_tumor/BraTS2021_00002/original_glcm_DifferenceAverage.nrrd"
# Computed original_glcm_DifferenceEntropy, stored as "./dataset/glcm/kernel3/non_tumor/BraTS2021_00002/original_glcm_DifferenceEntropy.nrrd"
# Computed original_glcm_DifferenceVariance, stored as "./dataset/glcm/kernel3/non_tumor/BraTS2021_00002/original_glcm_DifferenceVariance.nrrd"
# Computed original_glcm_Id, stored as "./dataset/glcm/kernel3/non_tumor/BraTS2021_00002/original_glcm_Id.nrrd"
# Computed original_glcm_Idm, stored as "./dataset/glcm/kernel3/non_tumor/BraTS2021_00002/original_glcm_Idm.nrrd"
# Computed original_glcm_Idmn, stored as "./dataset/glcm/kernel3/non_tumor/BraTS2021_00002/original_glcm_Idmn.nrrd"
# Computed original_glcm_Idn, stored as "./dataset/glcm/kernel3/non_tumor/BraTS2021_00002/original_glcm_Idn.nrrd"
# Computed original_glcm_Imc1, stored as "./dataset/glcm/kernel3/non_tumor/BraTS2021_00002/original_glcm_Imc1.nrrd"
# Computed original_glcm_Imc2, stored as "./dataset/glcm/kernel3/non_tumor/BraTS2021_00002/original_glcm_Imc2.nrrd"
# Computed original_glcm_InverseVariance, stored as "./dataset/glcm/kernel3/non_tumor/BraTS2021_00002/original_glcm_InverseVariance.nrrd"
# Computed original_glcm_JointAverage, stored as "./dataset/glcm/kernel3/non_tumor/BraTS2021_00002/original_glcm_JointAverage.nrrd"
# Computed original_glcm_JointEnergy, stored as "./dataset/glcm/kernel3/non_tumor/BraTS2021_00002/original_glcm_JointEnergy.nrrd"
# Computed original_glcm_JointEntropy, stored as "./dataset/glcm/kernel3/non_tumor/BraTS2021_00002/original_glcm_JointEntropy.nrrd"
# Computed original_glcm_MCC, stored as "./dataset/glcm/kernel3/non_tumor/BraTS2021_00002/original_glcm_MCC.nrrd"
# Computed original_glcm_MaximumProbability, stored as "./dataset/glcm/kernel3/non_tumor/BraTS2021_00002/original_glcm_MaximumProbability.nrrd"
# Computed original_glcm_SumAverage, stored as "./dataset/glcm/kernel3/non_tumor/BraTS2021_00002/original_glcm_SumAverage.nrrd"
# Computed original_glcm_SumEntropy, stored as "./dataset/glcm/kernel3/non_tumor/BraTS2021_00002/original_glcm_SumEntropy.nrrd"
# Computed original_glcm_SumSquares, stored as "./dataset/glcm/kernel3/non_tumor/BraTS2021_00002/original_glcm_SumSquares.nrrd"
# Starting BraTS2021_00003
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# Computed original_glcm_Autocorrelation, stored as "./dataset/glcm/kernel3/non_tumor/BraTS2021_00003/original_glcm_Autocorrelation.nrrd"
# Computed original_glcm_ClusterProminence, stored as "./dataset/glcm/kernel3/non_tumor/BraTS2021_00003/original_glcm_ClusterProminence.nrrd"
# Computed original_glcm_ClusterShade, stored as "./dataset/glcm/kernel3/non_tumor/BraTS2021_00003/original_glcm_ClusterShade.nrrd"
# Computed original_glcm_ClusterTendency, stored as "./dataset/glcm/kernel3/non_tumor/BraTS2021_00003/original_glcm_ClusterTendency.nrrd"
# Computed original_glcm_Contrast, stored as "./dataset/glcm/kernel3/non_tumor/BraTS2021_00003/original_glcm_Contrast.nrrd"
# Computed original_glcm_Correlation, stored as "./dataset/glcm/kernel3/non_tumor/BraTS2021_00003/original_glcm_Correlation.nrrd"
# Computed original_glcm_DifferenceAverage, stored as "./dataset/glcm/kernel3/non_tumor/BraTS2021_00003/original_glcm_DifferenceAverage.nrrd"
# Computed original_glcm_DifferenceEntropy, stored as "./dataset/glcm/kernel3/non_tumor/BraTS2021_00003/original_glcm_DifferenceEntropy.nrrd"
# Computed original_glcm_DifferenceVariance, stored as "./dataset/glcm/kernel3/non_tumor/BraTS2021_00003/original_glcm_DifferenceVariance.nrrd"
# Computed original_glcm_Id, stored as "./dataset/glcm/kernel3/non_tumor/BraTS2021_00003/original_glcm_Id.nrrd"
# Computed original_glcm_Idm, stored as "./dataset/glcm/kernel3/non_tumor/BraTS2021_00003/original_glcm_Idm.nrrd"
# Computed original_glcm_Idmn, stored as "./dataset/glcm/kernel3/non_tumor/BraTS2021_00003/original_glcm_Idmn.nrrd"
# Computed original_glcm_Idn, stored as "./dataset/glcm/kernel3/non_tumor/BraTS2021_00003/original_glcm_Idn.nrrd"
# Computed original_glcm_Imc1, stored as "./dataset/glcm/kernel3/non_tumor/BraTS2021_00003/original_glcm_Imc1.nrrd"
# Computed original_glcm_Imc2, stored as "./dataset/glcm/kernel3/non_tumor/BraTS2021_00003/original_glcm_Imc2.nrrd"
# Computed original_glcm_InverseVariance, stored as "./dataset/glcm/kernel3/non_tumor/BraTS2021_00003/original_glcm_InverseVariance.nrrd"
# Computed original_glcm_JointAverage, stored as "./dataset/glcm/kernel3/non_tumor/BraTS2021_00003/original_glcm_JointAverage.nrrd"
# Computed original_glcm_JointEnergy, stored as "./dataset/glcm/kernel3/non_tumor/BraTS2021_00003/original_glcm_JointEnergy.nrrd"
# Computed original_glcm_JointEntropy, stored as "./dataset/glcm/kernel3/non_tumor/BraTS2021_00003/original_glcm_JointEntropy.nrrd"
# Computed original_glcm_MCC, stored as "./dataset/glcm/kernel3/non_tumor/BraTS2021_00003/original_glcm_MCC.nrrd"
# Computed original_glcm_MaximumProbability, stored as "./dataset/glcm/kernel3/non_tumor/BraTS2021_00003/original_glcm_MaximumProbability.nrrd"
# Computed original_glcm_SumAverage, stored as "./dataset/glcm/kernel3/non_tumor/BraTS2021_00003/original_glcm_SumAverage.nrrd"
# Computed original_glcm_SumEntropy, stored as "./dataset/glcm/kernel3/non_tumor/BraTS2021_00003/original_glcm_SumEntropy.nrrd"
# Computed original_glcm_SumSquares, stored as "./dataset/glcm/kernel3/non_tumor/BraTS2021_00003/original_glcm_SumSquares.nrrd"
# Starting BraTS2021_00005
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# Computed original_glcm_Autocorrelation, stored as "./dataset/glcm/kernel3/non_tumor/BraTS2021_00005/original_glcm_Autocorrelation.nrrd"
# Computed original_glcm_ClusterProminence, stored as "./dataset/glcm/kernel3/non_tumor/BraTS2021_00005/original_glcm_ClusterProminence.nrrd"
# Computed original_glcm_ClusterShade, stored as "./dataset/glcm/kernel3/non_tumor/BraTS2021_00005/original_glcm_ClusterShade.nrrd"
# Computed original_glcm_ClusterTendency, stored as "./dataset/glcm/kernel3/non_tumor/BraTS2021_00005/original_glcm_ClusterTendency.nrrd"
# Computed original_glcm_Contrast, stored as "./dataset/glcm/kernel3/non_tumor/BraTS2021_00005/original_glcm_Contrast.nrrd"
# Computed original_glcm_Correlation, stored as "./dataset/glcm/kernel3/non_tumor/BraTS2021_00005/original_glcm_Correlation.nrrd"
# Computed original_glcm_DifferenceAverage, stored as "./dataset/glcm/kernel3/non_tumor/BraTS2021_00005/original_glcm_DifferenceAverage.nrrd"
# Computed original_glcm_DifferenceEntropy, stored as "./dataset/glcm/kernel3/non_tumor/BraTS2021_00005/original_glcm_DifferenceEntropy.nrrd"
# Computed original_glcm_DifferenceVariance, stored as "./dataset/glcm/kernel3/non_tumor/BraTS2021_00005/original_glcm_DifferenceVariance.nrrd"
# Computed original_glcm_Id, stored as "./dataset/glcm/kernel3/non_tumor/BraTS2021_00005/original_glcm_Id.nrrd"
# Computed original_glcm_Idm, stored as "./dataset/glcm/kernel3/non_tumor/BraTS2021_00005/original_glcm_Idm.nrrd"
# Computed original_glcm_Idmn, stored as "./dataset/glcm/kernel3/non_tumor/BraTS2021_00005/original_glcm_Idmn.nrrd"
# Computed original_glcm_Idn, stored as "./dataset/glcm/kernel3/non_tumor/BraTS2021_00005/original_glcm_Idn.nrrd"
# Computed original_glcm_Imc1, stored as "./dataset/glcm/kernel3/non_tumor/BraTS2021_00005/original_glcm_Imc1.nrrd"
# Computed original_glcm_Imc2, stored as "./dataset/glcm/kernel3/non_tumor/BraTS2021_00005/original_glcm_Imc2.nrrd"
# Computed original_glcm_InverseVariance, stored as "./dataset/glcm/kernel3/non_tumor/BraTS2021_00005/original_glcm_InverseVariance.nrrd"
# Computed original_glcm_JointAverage, stored as "./dataset/glcm/kernel3/non_tumor/BraTS2021_00005/original_glcm_JointAverage.nrrd"
# Computed original_glcm_JointEnergy, stored as "./dataset/glcm/kernel3/non_tumor/BraTS2021_00005/original_glcm_JointEnergy.nrrd"
# Computed original_glcm_JointEntropy, stored as "./dataset/glcm/kernel3/non_tumor/BraTS2021_00005/original_glcm_JointEntropy.nrrd"
# Computed original_glcm_MCC, stored as "./dataset/glcm/kernel3/non_tumor/BraTS2021_00005/original_glcm_MCC.nrrd"
# Computed original_glcm_MaximumProbability, stored as "./dataset/glcm/kernel3/non_tumor/BraTS2021_00005/original_glcm_MaximumProbability.nrrd"
# Computed original_glcm_SumAverage, stored as "./dataset/glcm/kernel3/non_tumor/BraTS2021_00005/original_glcm_SumAverage.nrrd"
# Computed original_glcm_SumEntropy, stored as "./dataset/glcm/kernel3/non_tumor/BraTS2021_00005/original_glcm_SumEntropy.nrrd"
# Computed original_glcm_SumSquares, stored as "./dataset/glcm/kernel3/non_tumor/BraTS2021_00005/original_glcm_SumSquares.nrrd"
# Starting BraTS2021_00006
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# Computed original_glcm_Autocorrelation, stored as "./dataset/glcm/kernel3/non_tumor/BraTS2021_00006/original_glcm_Autocorrelation.nrrd"
# Computed original_glcm_ClusterProminence, stored as "./dataset/glcm/kernel3/non_tumor/BraTS2021_00006/original_glcm_ClusterProminence.nrrd"
# Computed original_glcm_ClusterShade, stored as "./dataset/glcm/kernel3/non_tumor/BraTS2021_00006/original_glcm_ClusterShade.nrrd"
# Computed original_glcm_ClusterTendency, stored as "./dataset/glcm/kernel3/non_tumor/BraTS2021_00006/original_glcm_ClusterTendency.nrrd"
# Computed original_glcm_Contrast, stored as "./dataset/glcm/kernel3/non_tumor/BraTS2021_00006/original_glcm_Contrast.nrrd"
# Computed original_glcm_Correlation, stored as "./dataset/glcm/kernel3/non_tumor/BraTS2021_00006/original_glcm_Correlation.nrrd"
# Computed original_glcm_DifferenceAverage, stored as "./dataset/glcm/kernel3/non_tumor/BraTS2021_00006/original_glcm_DifferenceAverage.nrrd"
# Computed original_glcm_DifferenceEntropy, stored as "./dataset/glcm/kernel3/non_tumor/BraTS2021_00006/original_glcm_DifferenceEntropy.nrrd"
# Computed original_glcm_DifferenceVariance, stored as "./dataset/glcm/kernel3/non_tumor/BraTS2021_00006/original_glcm_DifferenceVariance.nrrd"
# Computed original_glcm_Id, stored as "./dataset/glcm/kernel3/non_tumor/BraTS2021_00006/original_glcm_Id.nrrd"
# Computed original_glcm_Idm, stored as "./dataset/glcm/kernel3/non_tumor/BraTS2021_00006/original_glcm_Idm.nrrd"
# Computed original_glcm_Idmn, stored as "./dataset/glcm/kernel3/non_tumor/BraTS2021_00006/original_glcm_Idmn.nrrd"
# Computed original_glcm_Idn, stored as "./dataset/glcm/kernel3/non_tumor/BraTS2021_00006/original_glcm_Idn.nrrd"
# Computed original_glcm_Imc1, stored as "./dataset/glcm/kernel3/non_tumor/BraTS2021_00006/original_glcm_Imc1.nrrd"
# Computed original_glcm_Imc2, stored as "./dataset/glcm/kernel3/non_tumor/BraTS2021_00006/original_glcm_Imc2.nrrd"
# Computed original_glcm_InverseVariance, stored as "./dataset/glcm/kernel3/non_tumor/BraTS2021_00006/original_glcm_InverseVariance.nrrd"
# Computed original_glcm_JointAverage, stored as "./dataset/glcm/kernel3/non_tumor/BraTS2021_00006/original_glcm_JointAverage.nrrd"
# Computed original_glcm_JointEnergy, stored as "./dataset/glcm/kernel3/non_tumor/BraTS2021_00006/original_glcm_JointEnergy.nrrd"
# Computed original_glcm_JointEntropy, stored as "./dataset/glcm/kernel3/non_tumor/BraTS2021_00006/original_glcm_JointEntropy.nrrd"
# Computed original_glcm_MCC, stored as "./dataset/glcm/kernel3/non_tumor/BraTS2021_00006/original_glcm_MCC.nrrd"
# Computed original_glcm_MaximumProbability, stored as "./dataset/glcm/kernel3/non_tumor/BraTS2021_00006/original_glcm_MaximumProbability.nrrd"
# Computed original_glcm_SumAverage, stored as "./dataset/glcm/kernel3/non_tumor/BraTS2021_00006/original_glcm_SumAverage.nrrd"
# Computed original_glcm_SumEntropy, stored as "./dataset/glcm/kernel3/non_tumor/BraTS2021_00006/original_glcm_SumEntropy.nrrd"
# Computed original_glcm_SumSquares, stored as "./dataset/glcm/kernel3/non_tumor/BraTS2021_00006/original_glcm_SumSquares.nrrd"
# Starting BraTS2021_00008
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# Computed original_glcm_Autocorrelation, stored as "./dataset/glcm/kernel3/non_tumor/BraTS2021_00008/original_glcm_Autocorrelation.nrrd"
# Computed original_glcm_ClusterProminence, stored as "./dataset/glcm/kernel3/non_tumor/BraTS2021_00008/original_glcm_ClusterProminence.nrrd"
# Computed original_glcm_ClusterShade, stored as "./dataset/glcm/kernel3/non_tumor/BraTS2021_00008/original_glcm_ClusterShade.nrrd"
# Computed original_glcm_ClusterTendency, stored as "./dataset/glcm/kernel3/non_tumor/BraTS2021_00008/original_glcm_ClusterTendency.nrrd"
# Computed original_glcm_Contrast, stored as "./dataset/glcm/kernel3/non_tumor/BraTS2021_00008/original_glcm_Contrast.nrrd"
# Computed original_glcm_Correlation, stored as "./dataset/glcm/kernel3/non_tumor/BraTS2021_00008/original_glcm_Correlation.nrrd"
# Computed original_glcm_DifferenceAverage, stored as "./dataset/glcm/kernel3/non_tumor/BraTS2021_00008/original_glcm_DifferenceAverage.nrrd"
# Computed original_glcm_DifferenceEntropy, stored as "./dataset/glcm/kernel3/non_tumor/BraTS2021_00008/original_glcm_DifferenceEntropy.nrrd"
# Computed original_glcm_DifferenceVariance, stored as "./dataset/glcm/kernel3/non_tumor/BraTS2021_00008/original_glcm_DifferenceVariance.nrrd"
# Computed original_glcm_Id, stored as "./dataset/glcm/kernel3/non_tumor/BraTS2021_00008/original_glcm_Id.nrrd"
# Computed original_glcm_Idm, stored as "./dataset/glcm/kernel3/non_tumor/BraTS2021_00008/original_glcm_Idm.nrrd"
# Computed original_glcm_Idmn, stored as "./dataset/glcm/kernel3/non_tumor/BraTS2021_00008/original_glcm_Idmn.nrrd"
# Computed original_glcm_Idn, stored as "./dataset/glcm/kernel3/non_tumor/BraTS2021_00008/original_glcm_Idn.nrrd"
# Computed original_glcm_Imc1, stored as "./dataset/glcm/kernel3/non_tumor/BraTS2021_00008/original_glcm_Imc1.nrrd"
# Computed original_glcm_Imc2, stored as "./dataset/glcm/kernel3/non_tumor/BraTS2021_00008/original_glcm_Imc2.nrrd"
# Computed original_glcm_InverseVariance, stored as "./dataset/glcm/kernel3/non_tumor/BraTS2021_00008/original_glcm_InverseVariance.nrrd"
# Computed original_glcm_JointAverage, stored as "./dataset/glcm/kernel3/non_tumor/BraTS2021_00008/original_glcm_JointAverage.nrrd"
# Computed original_glcm_JointEnergy, stored as "./dataset/glcm/kernel3/non_tumor/BraTS2021_00008/original_glcm_JointEnergy.nrrd"
# Computed original_glcm_JointEntropy, stored as "./dataset/glcm/kernel3/non_tumor/BraTS2021_00008/original_glcm_JointEntropy.nrrd"
# Computed original_glcm_MCC, stored as "./dataset/glcm/kernel3/non_tumor/BraTS2021_00008/original_glcm_MCC.nrrd"
# Computed original_glcm_MaximumProbability, stored as "./dataset/glcm/kernel3/non_tumor/BraTS2021_00008/original_glcm_MaximumProbability.nrrd"
# Computed original_glcm_SumAverage, stored as "./dataset/glcm/kernel3/non_tumor/BraTS2021_00008/original_glcm_SumAverage.nrrd"
# Computed original_glcm_SumEntropy, stored as "./dataset/glcm/kernel3/non_tumor/BraTS2021_00008/original_glcm_SumEntropy.nrrd"
# Computed original_glcm_SumSquares, stored as "./dataset/glcm/kernel3/non_tumor/BraTS2021_00008/original_glcm_SumSquares.nrrd"
# Starting BraTS2021_00009
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# Computed original_glcm_Autocorrelation, stored as "./dataset/glcm/kernel3/non_tumor/BraTS2021_00009/original_glcm_Autocorrelation.nrrd"
# Computed original_glcm_ClusterProminence, stored as "./dataset/glcm/kernel3/non_tumor/BraTS2021_00009/original_glcm_ClusterProminence.nrrd"
# Computed original_glcm_ClusterShade, stored as "./dataset/glcm/kernel3/non_tumor/BraTS2021_00009/original_glcm_ClusterShade.nrrd"
# Computed original_glcm_ClusterTendency, stored as "./dataset/glcm/kernel3/non_tumor/BraTS2021_00009/original_glcm_ClusterTendency.nrrd"
# Computed original_glcm_Contrast, stored as "./dataset/glcm/kernel3/non_tumor/BraTS2021_00009/original_glcm_Contrast.nrrd"
# Computed original_glcm_Correlation, stored as "./dataset/glcm/kernel3/non_tumor/BraTS2021_00009/original_glcm_Correlation.nrrd"
# Computed original_glcm_DifferenceAverage, stored as "./dataset/glcm/kernel3/non_tumor/BraTS2021_00009/original_glcm_DifferenceAverage.nrrd"
# Computed original_glcm_DifferenceEntropy, stored as "./dataset/glcm/kernel3/non_tumor/BraTS2021_00009/original_glcm_DifferenceEntropy.nrrd"
# Computed original_glcm_DifferenceVariance, stored as "./dataset/glcm/kernel3/non_tumor/BraTS2021_00009/original_glcm_DifferenceVariance.nrrd"
# Computed original_glcm_Id, stored as "./dataset/glcm/kernel3/non_tumor/BraTS2021_00009/original_glcm_Id.nrrd"
# Computed original_glcm_Idm, stored as "./dataset/glcm/kernel3/non_tumor/BraTS2021_00009/original_glcm_Idm.nrrd"
# Computed original_glcm_Idmn, stored as "./dataset/glcm/kernel3/non_tumor/BraTS2021_00009/original_glcm_Idmn.nrrd"
# Computed original_glcm_Idn, stored as "./dataset/glcm/kernel3/non_tumor/BraTS2021_00009/original_glcm_Idn.nrrd"
# Computed original_glcm_Imc1, stored as "./dataset/glcm/kernel3/non_tumor/BraTS2021_00009/original_glcm_Imc1.nrrd"
# Computed original_glcm_Imc2, stored as "./dataset/glcm/kernel3/non_tumor/BraTS2021_00009/original_glcm_Imc2.nrrd"
# Computed original_glcm_InverseVariance, stored as "./dataset/glcm/kernel3/non_tumor/BraTS2021_00009/original_glcm_InverseVariance.nrrd"
# Computed original_glcm_JointAverage, stored as "./dataset/glcm/kernel3/non_tumor/BraTS2021_00009/original_glcm_JointAverage.nrrd"
# Computed original_glcm_JointEnergy, stored as "./dataset/glcm/kernel3/non_tumor/BraTS2021_00009/original_glcm_JointEnergy.nrrd"
# Computed original_glcm_JointEntropy, stored as "./dataset/glcm/kernel3/non_tumor/BraTS2021_00009/original_glcm_JointEntropy.nrrd"
# Computed original_glcm_MCC, stored as "./dataset/glcm/kernel3/non_tumor/BraTS2021_00009/original_glcm_MCC.nrrd"
# Computed original_glcm_MaximumProbability, stored as "./dataset/glcm/kernel3/non_tumor/BraTS2021_00009/original_glcm_MaximumProbability.nrrd"
# Computed original_glcm_SumAverage, stored as "./dataset/glcm/kernel3/non_tumor/BraTS2021_00009/original_glcm_SumAverage.nrrd"
# Computed original_glcm_SumEntropy, stored as "./dataset/glcm/kernel3/non_tumor/BraTS2021_00009/original_glcm_SumEntropy.nrrd"
# Computed original_glcm_SumSquares, stored as "./dataset/glcm/kernel3/non_tumor/BraTS2021_00009/original_glcm_SumSquares.nrrd"
# Starting BraTS2021_00011
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# Computed original_glcm_Autocorrelation, stored as "./dataset/glcm/kernel3/non_tumor/BraTS2021_00011/original_glcm_Autocorrelation.nrrd"
# Computed original_glcm_ClusterProminence, stored as "./dataset/glcm/kernel3/non_tumor/BraTS2021_00011/original_glcm_ClusterProminence.nrrd"
# Computed original_glcm_ClusterShade, stored as "./dataset/glcm/kernel3/non_tumor/BraTS2021_00011/original_glcm_ClusterShade.nrrd"
# Computed original_glcm_ClusterTendency, stored as "./dataset/glcm/kernel3/non_tumor/BraTS2021_00011/original_glcm_ClusterTendency.nrrd"
# Computed original_glcm_Contrast, stored as "./dataset/glcm/kernel3/non_tumor/BraTS2021_00011/original_glcm_Contrast.nrrd"
# Computed original_glcm_Correlation, stored as "./dataset/glcm/kernel3/non_tumor/BraTS2021_00011/original_glcm_Correlation.nrrd"
# Computed original_glcm_DifferenceAverage, stored as "./dataset/glcm/kernel3/non_tumor/BraTS2021_00011/original_glcm_DifferenceAverage.nrrd"
# Computed original_glcm_DifferenceEntropy, stored as "./dataset/glcm/kernel3/non_tumor/BraTS2021_00011/original_glcm_DifferenceEntropy.nrrd"
# Computed original_glcm_DifferenceVariance, stored as "./dataset/glcm/kernel3/non_tumor/BraTS2021_00011/original_glcm_DifferenceVariance.nrrd"
# Computed original_glcm_Id, stored as "./dataset/glcm/kernel3/non_tumor/BraTS2021_00011/original_glcm_Id.nrrd"
# Computed original_glcm_Idm, stored as "./dataset/glcm/kernel3/non_tumor/BraTS2021_00011/original_glcm_Idm.nrrd"
# Computed original_glcm_Idmn, stored as "./dataset/glcm/kernel3/non_tumor/BraTS2021_00011/original_glcm_Idmn.nrrd"
# Computed original_glcm_Idn, stored as "./dataset/glcm/kernel3/non_tumor/BraTS2021_00011/original_glcm_Idn.nrrd"
# Computed original_glcm_Imc1, stored as "./dataset/glcm/kernel3/non_tumor/BraTS2021_00011/original_glcm_Imc1.nrrd"
# Computed original_glcm_Imc2, stored as "./dataset/glcm/kernel3/non_tumor/BraTS2021_00011/original_glcm_Imc2.nrrd"
# Computed original_glcm_InverseVariance, stored as "./dataset/glcm/kernel3/non_tumor/BraTS2021_00011/original_glcm_InverseVariance.nrrd"
# Computed original_glcm_JointAverage, stored as "./dataset/glcm/kernel3/non_tumor/BraTS2021_00011/original_glcm_JointAverage.nrrd"
# Computed original_glcm_JointEnergy, stored as "./dataset/glcm/kernel3/non_tumor/BraTS2021_00011/original_glcm_JointEnergy.nrrd"
# Computed original_glcm_JointEntropy, stored as "./dataset/glcm/kernel3/non_tumor/BraTS2021_00011/original_glcm_JointEntropy.nrrd"
# Computed original_glcm_MCC, stored as "./dataset/glcm/kernel3/non_tumor/BraTS2021_00011/original_glcm_MCC.nrrd"
# Computed original_glcm_MaximumProbability, stored as "./dataset/glcm/kernel3/non_tumor/BraTS2021_00011/original_glcm_MaximumProbability.nrrd"
# Computed original_glcm_SumAverage, stored as "./dataset/glcm/kernel3/non_tumor/BraTS2021_00011/original_glcm_SumAverage.nrrd"
# Computed original_glcm_SumEntropy, stored as "./dataset/glcm/kernel3/non_tumor/BraTS2021_00011/original_glcm_SumEntropy.nrrd"
# Computed original_glcm_SumSquares, stored as "./dataset/glcm/kernel3/non_tumor/BraTS2021_00011/original_glcm_SumSquares.nrrd"
# Starting BraTS2021_00012
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# Computed original_glcm_Autocorrelation, stored as "./dataset/glcm/kernel3/non_tumor/BraTS2021_00012/original_glcm_Autocorrelation.nrrd"
# Computed original_glcm_ClusterProminence, stored as "./dataset/glcm/kernel3/non_tumor/BraTS2021_00012/original_glcm_ClusterProminence.nrrd"
# Computed original_glcm_ClusterShade, stored as "./dataset/glcm/kernel3/non_tumor/BraTS2021_00012/original_glcm_ClusterShade.nrrd"
# Computed original_glcm_ClusterTendency, stored as "./dataset/glcm/kernel3/non_tumor/BraTS2021_00012/original_glcm_ClusterTendency.nrrd"
# Computed original_glcm_Contrast, stored as "./dataset/glcm/kernel3/non_tumor/BraTS2021_00012/original_glcm_Contrast.nrrd"
# Computed original_glcm_Correlation, stored as "./dataset/glcm/kernel3/non_tumor/BraTS2021_00012/original_glcm_Correlation.nrrd"
# Computed original_glcm_DifferenceAverage, stored as "./dataset/glcm/kernel3/non_tumor/BraTS2021_00012/original_glcm_DifferenceAverage.nrrd"
# Computed original_glcm_DifferenceEntropy, stored as "./dataset/glcm/kernel3/non_tumor/BraTS2021_00012/original_glcm_DifferenceEntropy.nrrd"
# Computed original_glcm_DifferenceVariance, stored as "./dataset/glcm/kernel3/non_tumor/BraTS2021_00012/original_glcm_DifferenceVariance.nrrd"
# Computed original_glcm_Id, stored as "./dataset/glcm/kernel3/non_tumor/BraTS2021_00012/original_glcm_Id.nrrd"
# Computed original_glcm_Idm, stored as "./dataset/glcm/kernel3/non_tumor/BraTS2021_00012/original_glcm_Idm.nrrd"
# Computed original_glcm_Idmn, stored as "./dataset/glcm/kernel3/non_tumor/BraTS2021_00012/original_glcm_Idmn.nrrd"
# Computed original_glcm_Idn, stored as "./dataset/glcm/kernel3/non_tumor/BraTS2021_00012/original_glcm_Idn.nrrd"
# Computed original_glcm_Imc1, stored as "./dataset/glcm/kernel3/non_tumor/BraTS2021_00012/original_glcm_Imc1.nrrd"
# Computed original_glcm_Imc2, stored as "./dataset/glcm/kernel3/non_tumor/BraTS2021_00012/original_glcm_Imc2.nrrd"
# Computed original_glcm_InverseVariance, stored as "./dataset/glcm/kernel3/non_tumor/BraTS2021_00012/original_glcm_InverseVariance.nrrd"
# Computed original_glcm_JointAverage, stored as "./dataset/glcm/kernel3/non_tumor/BraTS2021_00012/original_glcm_JointAverage.nrrd"
# Computed original_glcm_JointEnergy, stored as "./dataset/glcm/kernel3/non_tumor/BraTS2021_00012/original_glcm_JointEnergy.nrrd"
# Computed original_glcm_JointEntropy, stored as "./dataset/glcm/kernel3/non_tumor/BraTS2021_00012/original_glcm_JointEntropy.nrrd"
# Computed original_glcm_MCC, stored as "./dataset/glcm/kernel3/non_tumor/BraTS2021_00012/original_glcm_MCC.nrrd"
# Computed original_glcm_MaximumProbability, stored as "./dataset/glcm/kernel3/non_tumor/BraTS2021_00012/original_glcm_MaximumProbability.nrrd"
# Computed original_glcm_SumAverage, stored as "./dataset/glcm/kernel3/non_tumor/BraTS2021_00012/original_glcm_SumAverage.nrrd"
# Computed original_glcm_SumEntropy, stored as "./dataset/glcm/kernel3/non_tumor/BraTS2021_00012/original_glcm_SumEntropy.nrrd"
# Computed original_glcm_SumSquares, stored as "./dataset/glcm/kernel3/non_tumor/BraTS2021_00012/original_glcm_SumSquares.nrrd"
# Starting BraTS2021_00014
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# Computed original_glcm_Autocorrelation, stored as "./dataset/glcm/kernel3/non_tumor/BraTS2021_00014/original_glcm_Autocorrelation.nrrd"
# Computed original_glcm_ClusterProminence, stored as "./dataset/glcm/kernel3/non_tumor/BraTS2021_00014/original_glcm_ClusterProminence.nrrd"
# Computed original_glcm_ClusterShade, stored as "./dataset/glcm/kernel3/non_tumor/BraTS2021_00014/original_glcm_ClusterShade.nrrd"
# Computed original_glcm_ClusterTendency, stored as "./dataset/glcm/kernel3/non_tumor/BraTS2021_00014/original_glcm_ClusterTendency.nrrd"
# Computed original_glcm_Contrast, stored as "./dataset/glcm/kernel3/non_tumor/BraTS2021_00014/original_glcm_Contrast.nrrd"
# Computed original_glcm_Correlation, stored as "./dataset/glcm/kernel3/non_tumor/BraTS2021_00014/original_glcm_Correlation.nrrd"
# Computed original_glcm_DifferenceAverage, stored as "./dataset/glcm/kernel3/non_tumor/BraTS2021_00014/original_glcm_DifferenceAverage.nrrd"
# Computed original_glcm_DifferenceEntropy, stored as "./dataset/glcm/kernel3/non_tumor/BraTS2021_00014/original_glcm_DifferenceEntropy.nrrd"
# Computed original_glcm_DifferenceVariance, stored as "./dataset/glcm/kernel3/non_tumor/BraTS2021_00014/original_glcm_DifferenceVariance.nrrd"
# Computed original_glcm_Id, stored as "./dataset/glcm/kernel3/non_tumor/BraTS2021_00014/original_glcm_Id.nrrd"
# Computed original_glcm_Idm, stored as "./dataset/glcm/kernel3/non_tumor/BraTS2021_00014/original_glcm_Idm.nrrd"
# Computed original_glcm_Idmn, stored as "./dataset/glcm/kernel3/non_tumor/BraTS2021_00014/original_glcm_Idmn.nrrd"
# Computed original_glcm_Idn, stored as "./dataset/glcm/kernel3/non_tumor/BraTS2021_00014/original_glcm_Idn.nrrd"
# Computed original_glcm_Imc1, stored as "./dataset/glcm/kernel3/non_tumor/BraTS2021_00014/original_glcm_Imc1.nrrd"
# Computed original_glcm_Imc2, stored as "./dataset/glcm/kernel3/non_tumor/BraTS2021_00014/original_glcm_Imc2.nrrd"
# Computed original_glcm_InverseVariance, stored as "./dataset/glcm/kernel3/non_tumor/BraTS2021_00014/original_glcm_InverseVariance.nrrd"
# Computed original_glcm_JointAverage, stored as "./dataset/glcm/kernel3/non_tumor/BraTS2021_00014/original_glcm_JointAverage.nrrd"
# Computed original_glcm_JointEnergy, stored as "./dataset/glcm/kernel3/non_tumor/BraTS2021_00014/original_glcm_JointEnergy.nrrd"
# Computed original_glcm_JointEntropy, stored as "./dataset/glcm/kernel3/non_tumor/BraTS2021_00014/original_glcm_JointEntropy.nrrd"
# Computed original_glcm_MCC, stored as "./dataset/glcm/kernel3/non_tumor/BraTS2021_00014/original_glcm_MCC.nrrd"
# Computed original_glcm_MaximumProbability, stored as "./dataset/glcm/kernel3/non_tumor/BraTS2021_00014/original_glcm_MaximumProbability.nrrd"
# Computed original_glcm_SumAverage, stored as "./dataset/glcm/kernel3/non_tumor/BraTS2021_00014/original_glcm_SumAverage.nrrd"
# Computed original_glcm_SumEntropy, stored as "./dataset/glcm/kernel3/non_tumor/BraTS2021_00014/original_glcm_SumEntropy.nrrd"
# Computed original_glcm_SumSquares, stored as "./dataset/glcm/kernel3/non_tumor/BraTS2021_00014/original_glcm_SumSquares.nrrd"
# Starting BraTS2021_00016
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# Computed original_glcm_Autocorrelation, stored as "./dataset/glcm/kernel3/non_tumor/BraTS2021_00016/original_glcm_Autocorrelation.nrrd"
# Computed original_glcm_ClusterProminence, stored as "./dataset/glcm/kernel3/non_tumor/BraTS2021_00016/original_glcm_ClusterProminence.nrrd"
# Computed original_glcm_ClusterShade, stored as "./dataset/glcm/kernel3/non_tumor/BraTS2021_00016/original_glcm_ClusterShade.nrrd"
# Computed original_glcm_ClusterTendency, stored as "./dataset/glcm/kernel3/non_tumor/BraTS2021_00016/original_glcm_ClusterTendency.nrrd"
# Computed original_glcm_Contrast, stored as "./dataset/glcm/kernel3/non_tumor/BraTS2021_00016/original_glcm_Contrast.nrrd"
# Computed original_glcm_Correlation, stored as "./dataset/glcm/kernel3/non_tumor/BraTS2021_00016/original_glcm_Correlation.nrrd"
# Computed original_glcm_DifferenceAverage, stored as "./dataset/glcm/kernel3/non_tumor/BraTS2021_00016/original_glcm_DifferenceAverage.nrrd"
# Computed original_glcm_DifferenceEntropy, stored as "./dataset/glcm/kernel3/non_tumor/BraTS2021_00016/original_glcm_DifferenceEntropy.nrrd"
# Computed original_glcm_DifferenceVariance, stored as "./dataset/glcm/kernel3/non_tumor/BraTS2021_00016/original_glcm_DifferenceVariance.nrrd"
# Computed original_glcm_Id, stored as "./dataset/glcm/kernel3/non_tumor/BraTS2021_00016/original_glcm_Id.nrrd"
# Computed original_glcm_Idm, stored as "./dataset/glcm/kernel3/non_tumor/BraTS2021_00016/original_glcm_Idm.nrrd"
# Computed original_glcm_Idmn, stored as "./dataset/glcm/kernel3/non_tumor/BraTS2021_00016/original_glcm_Idmn.nrrd"
# Computed original_glcm_Idn, stored as "./dataset/glcm/kernel3/non_tumor/BraTS2021_00016/original_glcm_Idn.nrrd"
# Computed original_glcm_Imc1, stored as "./dataset/glcm/kernel3/non_tumor/BraTS2021_00016/original_glcm_Imc1.nrrd"
# Computed original_glcm_Imc2, stored as "./dataset/glcm/kernel3/non_tumor/BraTS2021_00016/original_glcm_Imc2.nrrd"
# Computed original_glcm_InverseVariance, stored as "./dataset/glcm/kernel3/non_tumor/BraTS2021_00016/original_glcm_InverseVariance.nrrd"
# Computed original_glcm_JointAverage, stored as "./dataset/glcm/kernel3/non_tumor/BraTS2021_00016/original_glcm_JointAverage.nrrd"
# Computed original_glcm_JointEnergy, stored as "./dataset/glcm/kernel3/non_tumor/BraTS2021_00016/original_glcm_JointEnergy.nrrd"
# Computed original_glcm_JointEntropy, stored as "./dataset/glcm/kernel3/non_tumor/BraTS2021_00016/original_glcm_JointEntropy.nrrd"
# Computed original_glcm_MCC, stored as "./dataset/glcm/kernel3/non_tumor/BraTS2021_00016/original_glcm_MCC.nrrd"
# Computed original_glcm_MaximumProbability, stored as "./dataset/glcm/kernel3/non_tumor/BraTS2021_00016/original_glcm_MaximumProbability.nrrd"
# Computed original_glcm_SumAverage, stored as "./dataset/glcm/kernel3/non_tumor/BraTS2021_00016/original_glcm_SumAverage.nrrd"
# Computed original_glcm_SumEntropy, stored as "./dataset/glcm/kernel3/non_tumor/BraTS2021_00016/original_glcm_SumEntropy.nrrd"
# Computed original_glcm_SumSquares, stored as "./dataset/glcm/kernel3/non_tumor/BraTS2021_00016/original_glcm_SumSquares.nrrd"
# Starting BraTS2021_00017
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# Computed original_glcm_Autocorrelation, stored as "./dataset/glcm/kernel3/non_tumor/BraTS2021_00017/original_glcm_Autocorrelation.nrrd"
# Computed original_glcm_ClusterProminence, stored as "./dataset/glcm/kernel3/non_tumor/BraTS2021_00017/original_glcm_ClusterProminence.nrrd"
# Computed original_glcm_ClusterShade, stored as "./dataset/glcm/kernel3/non_tumor/BraTS2021_00017/original_glcm_ClusterShade.nrrd"
# Computed original_glcm_ClusterTendency, stored as "./dataset/glcm/kernel3/non_tumor/BraTS2021_00017/original_glcm_ClusterTendency.nrrd"
# Computed original_glcm_Contrast, stored as "./dataset/glcm/kernel3/non_tumor/BraTS2021_00017/original_glcm_Contrast.nrrd"
# Computed original_glcm_Correlation, stored as "./dataset/glcm/kernel3/non_tumor/BraTS2021_00017/original_glcm_Correlation.nrrd"
# Computed original_glcm_DifferenceAverage, stored as "./dataset/glcm/kernel3/non_tumor/BraTS2021_00017/original_glcm_DifferenceAverage.nrrd"
# Computed original_glcm_DifferenceEntropy, stored as "./dataset/glcm/kernel3/non_tumor/BraTS2021_00017/original_glcm_DifferenceEntropy.nrrd"
# Computed original_glcm_DifferenceVariance, stored as "./dataset/glcm/kernel3/non_tumor/BraTS2021_00017/original_glcm_DifferenceVariance.nrrd"
# Computed original_glcm_Id, stored as "./dataset/glcm/kernel3/non_tumor/BraTS2021_00017/original_glcm_Id.nrrd"
# Computed original_glcm_Idm, stored as "./dataset/glcm/kernel3/non_tumor/BraTS2021_00017/original_glcm_Idm.nrrd"
# Computed original_glcm_Idmn, stored as "./dataset/glcm/kernel3/non_tumor/BraTS2021_00017/original_glcm_Idmn.nrrd"
# Computed original_glcm_Idn, stored as "./dataset/glcm/kernel3/non_tumor/BraTS2021_00017/original_glcm_Idn.nrrd"
# Computed original_glcm_Imc1, stored as "./dataset/glcm/kernel3/non_tumor/BraTS2021_00017/original_glcm_Imc1.nrrd"
# Computed original_glcm_Imc2, stored as "./dataset/glcm/kernel3/non_tumor/BraTS2021_00017/original_glcm_Imc2.nrrd"
# Computed original_glcm_InverseVariance, stored as "./dataset/glcm/kernel3/non_tumor/BraTS2021_00017/original_glcm_InverseVariance.nrrd"
# Computed original_glcm_JointAverage, stored as "./dataset/glcm/kernel3/non_tumor/BraTS2021_00017/original_glcm_JointAverage.nrrd"
# Computed original_glcm_JointEnergy, stored as "./dataset/glcm/kernel3/non_tumor/BraTS2021_00017/original_glcm_JointEnergy.nrrd"
# Computed original_glcm_JointEntropy, stored as "./dataset/glcm/kernel3/non_tumor/BraTS2021_00017/original_glcm_JointEntropy.nrrd"
# Computed original_glcm_MCC, stored as "./dataset/glcm/kernel3/non_tumor/BraTS2021_00017/original_glcm_MCC.nrrd"
# Computed original_glcm_MaximumProbability, stored as "./dataset/glcm/kernel3/non_tumor/BraTS2021_00017/original_glcm_MaximumProbability.nrrd"
# Computed original_glcm_SumAverage, stored as "./dataset/glcm/kernel3/non_tumor/BraTS2021_00017/original_glcm_SumAverage.nrrd"
# Computed original_glcm_SumEntropy, stored as "./dataset/glcm/kernel3/non_tumor/BraTS2021_00017/original_glcm_SumEntropy.nrrd"
# Computed original_glcm_SumSquares, stored as "./dataset/glcm/kernel3/non_tumor/BraTS2021_00017/original_glcm_SumSquares.nrrd"
# Starting BraTS2021_00018
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# Computed original_glcm_Autocorrelation, stored as "./dataset/glcm/kernel3/non_tumor/BraTS2021_00018/original_glcm_Autocorrelation.nrrd"
# Computed original_glcm_ClusterProminence, stored as "./dataset/glcm/kernel3/non_tumor/BraTS2021_00018/original_glcm_ClusterProminence.nrrd"
# Computed original_glcm_ClusterShade, stored as "./dataset/glcm/kernel3/non_tumor/BraTS2021_00018/original_glcm_ClusterShade.nrrd"
# Computed original_glcm_ClusterTendency, stored as "./dataset/glcm/kernel3/non_tumor/BraTS2021_00018/original_glcm_ClusterTendency.nrrd"
# Computed original_glcm_Contrast, stored as "./dataset/glcm/kernel3/non_tumor/BraTS2021_00018/original_glcm_Contrast.nrrd"
# Computed original_glcm_Correlation, stored as "./dataset/glcm/kernel3/non_tumor/BraTS2021_00018/original_glcm_Correlation.nrrd"
# Computed original_glcm_DifferenceAverage, stored as "./dataset/glcm/kernel3/non_tumor/BraTS2021_00018/original_glcm_DifferenceAverage.nrrd"
# Computed original_glcm_DifferenceEntropy, stored as "./dataset/glcm/kernel3/non_tumor/BraTS2021_00018/original_glcm_DifferenceEntropy.nrrd"
# Computed original_glcm_DifferenceVariance, stored as "./dataset/glcm/kernel3/non_tumor/BraTS2021_00018/original_glcm_DifferenceVariance.nrrd"
# Computed original_glcm_Id, stored as "./dataset/glcm/kernel3/non_tumor/BraTS2021_00018/original_glcm_Id.nrrd"
# Computed original_glcm_Idm, stored as "./dataset/glcm/kernel3/non_tumor/BraTS2021_00018/original_glcm_Idm.nrrd"
# Computed original_glcm_Idmn, stored as "./dataset/glcm/kernel3/non_tumor/BraTS2021_00018/original_glcm_Idmn.nrrd"
# Computed original_glcm_Idn, stored as "./dataset/glcm/kernel3/non_tumor/BraTS2021_00018/original_glcm_Idn.nrrd"
# Computed original_glcm_Imc1, stored as "./dataset/glcm/kernel3/non_tumor/BraTS2021_00018/original_glcm_Imc1.nrrd"
# Computed original_glcm_Imc2, stored as "./dataset/glcm/kernel3/non_tumor/BraTS2021_00018/original_glcm_Imc2.nrrd"
# Computed original_glcm_InverseVariance, stored as "./dataset/glcm/kernel3/non_tumor/BraTS2021_00018/original_glcm_InverseVariance.nrrd"
# Computed original_glcm_JointAverage, stored as "./dataset/glcm/kernel3/non_tumor/BraTS2021_00018/original_glcm_JointAverage.nrrd"
# Computed original_glcm_JointEnergy, stored as "./dataset/glcm/kernel3/non_tumor/BraTS2021_00018/original_glcm_JointEnergy.nrrd"
# Computed original_glcm_JointEntropy, stored as "./dataset/glcm/kernel3/non_tumor/BraTS2021_00018/original_glcm_JointEntropy.nrrd"
# Computed original_glcm_MCC, stored as "./dataset/glcm/kernel3/non_tumor/BraTS2021_00018/original_glcm_MCC.nrrd"
# Computed original_glcm_MaximumProbability, stored as "./dataset/glcm/kernel3/non_tumor/BraTS2021_00018/original_glcm_MaximumProbability.nrrd"
# Computed original_glcm_SumAverage, stored as "./dataset/glcm/kernel3/non_tumor/BraTS2021_00018/original_glcm_SumAverage.nrrd"
# Computed original_glcm_SumEntropy, stored as "./dataset/glcm/kernel3/non_tumor/BraTS2021_00018/original_glcm_SumEntropy.nrrd"
# Computed original_glcm_SumSquares, stored as "./dataset/glcm/kernel3/non_tumor/BraTS2021_00018/original_glcm_SumSquares.nrrd"
# Starting BraTS2021_00019
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# Computed original_glcm_Autocorrelation, stored as "./dataset/glcm/kernel3/non_tumor/BraTS2021_00019/original_glcm_Autocorrelation.nrrd"
# Computed original_glcm_ClusterProminence, stored as "./dataset/glcm/kernel3/non_tumor/BraTS2021_00019/original_glcm_ClusterProminence.nrrd"
# Computed original_glcm_ClusterShade, stored as "./dataset/glcm/kernel3/non_tumor/BraTS2021_00019/original_glcm_ClusterShade.nrrd"
# Computed original_glcm_ClusterTendency, stored as "./dataset/glcm/kernel3/non_tumor/BraTS2021_00019/original_glcm_ClusterTendency.nrrd"
# Computed original_glcm_Contrast, stored as "./dataset/glcm/kernel3/non_tumor/BraTS2021_00019/original_glcm_Contrast.nrrd"
# Computed original_glcm_Correlation, stored as "./dataset/glcm/kernel3/non_tumor/BraTS2021_00019/original_glcm_Correlation.nrrd"
# Computed original_glcm_DifferenceAverage, stored as "./dataset/glcm/kernel3/non_tumor/BraTS2021_00019/original_glcm_DifferenceAverage.nrrd"
# Computed original_glcm_DifferenceEntropy, stored as "./dataset/glcm/kernel3/non_tumor/BraTS2021_00019/original_glcm_DifferenceEntropy.nrrd"
# Computed original_glcm_DifferenceVariance, stored as "./dataset/glcm/kernel3/non_tumor/BraTS2021_00019/original_glcm_DifferenceVariance.nrrd"
# Computed original_glcm_Id, stored as "./dataset/glcm/kernel3/non_tumor/BraTS2021_00019/original_glcm_Id.nrrd"
# Computed original_glcm_Idm, stored as "./dataset/glcm/kernel3/non_tumor/BraTS2021_00019/original_glcm_Idm.nrrd"
# Computed original_glcm_Idmn, stored as "./dataset/glcm/kernel3/non_tumor/BraTS2021_00019/original_glcm_Idmn.nrrd"
# Computed original_glcm_Idn, stored as "./dataset/glcm/kernel3/non_tumor/BraTS2021_00019/original_glcm_Idn.nrrd"
# Computed original_glcm_Imc1, stored as "./dataset/glcm/kernel3/non_tumor/BraTS2021_00019/original_glcm_Imc1.nrrd"
# Computed original_glcm_Imc2, stored as "./dataset/glcm/kernel3/non_tumor/BraTS2021_00019/original_glcm_Imc2.nrrd"
# Computed original_glcm_InverseVariance, stored as "./dataset/glcm/kernel3/non_tumor/BraTS2021_00019/original_glcm_InverseVariance.nrrd"
# Computed original_glcm_JointAverage, stored as "./dataset/glcm/kernel3/non_tumor/BraTS2021_00019/original_glcm_JointAverage.nrrd"
# Computed original_glcm_JointEnergy, stored as "./dataset/glcm/kernel3/non_tumor/BraTS2021_00019/original_glcm_JointEnergy.nrrd"
# Computed original_glcm_JointEntropy, stored as "./dataset/glcm/kernel3/non_tumor/BraTS2021_00019/original_glcm_JointEntropy.nrrd"
# Computed original_glcm_MCC, stored as "./dataset/glcm/kernel3/non_tumor/BraTS2021_00019/original_glcm_MCC.nrrd"
# Computed original_glcm_MaximumProbability, stored as "./dataset/glcm/kernel3/non_tumor/BraTS2021_00019/original_glcm_MaximumProbability.nrrd"
# Computed original_glcm_SumAverage, stored as "./dataset/glcm/kernel3/non_tumor/BraTS2021_00019/original_glcm_SumAverage.nrrd"
# Computed original_glcm_SumEntropy, stored as "./dataset/glcm/kernel3/non_tumor/BraTS2021_00019/original_glcm_SumEntropy.nrrd"
# Computed original_glcm_SumSquares, stored as "./dataset/glcm/kernel3/non_tumor/BraTS2021_00019/original_glcm_SumSquares.nrrd"
# Starting BraTS2021_00020
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# Computed original_glcm_Autocorrelation, stored as "./dataset/glcm/kernel3/non_tumor/BraTS2021_00020/original_glcm_Autocorrelation.nrrd"
# Computed original_glcm_ClusterProminence, stored as "./dataset/glcm/kernel3/non_tumor/BraTS2021_00020/original_glcm_ClusterProminence.nrrd"
# Computed original_glcm_ClusterShade, stored as "./dataset/glcm/kernel3/non_tumor/BraTS2021_00020/original_glcm_ClusterShade.nrrd"
# Computed original_glcm_ClusterTendency, stored as "./dataset/glcm/kernel3/non_tumor/BraTS2021_00020/original_glcm_ClusterTendency.nrrd"
# Computed original_glcm_Contrast, stored as "./dataset/glcm/kernel3/non_tumor/BraTS2021_00020/original_glcm_Contrast.nrrd"
# Computed original_glcm_Correlation, stored as "./dataset/glcm/kernel3/non_tumor/BraTS2021_00020/original_glcm_Correlation.nrrd"
# Computed original_glcm_DifferenceAverage, stored as "./dataset/glcm/kernel3/non_tumor/BraTS2021_00020/original_glcm_DifferenceAverage.nrrd"
# Computed original_glcm_DifferenceEntropy, stored as "./dataset/glcm/kernel3/non_tumor/BraTS2021_00020/original_glcm_DifferenceEntropy.nrrd"
# Computed original_glcm_DifferenceVariance, stored as "./dataset/glcm/kernel3/non_tumor/BraTS2021_00020/original_glcm_DifferenceVariance.nrrd"
# Computed original_glcm_Id, stored as "./dataset/glcm/kernel3/non_tumor/BraTS2021_00020/original_glcm_Id.nrrd"
# Computed original_glcm_Idm, stored as "./dataset/glcm/kernel3/non_tumor/BraTS2021_00020/original_glcm_Idm.nrrd"
# Computed original_glcm_Idmn, stored as "./dataset/glcm/kernel3/non_tumor/BraTS2021_00020/original_glcm_Idmn.nrrd"
# Computed original_glcm_Idn, stored as "./dataset/glcm/kernel3/non_tumor/BraTS2021_00020/original_glcm_Idn.nrrd"
# Computed original_glcm_Imc1, stored as "./dataset/glcm/kernel3/non_tumor/BraTS2021_00020/original_glcm_Imc1.nrrd"
# Computed original_glcm_Imc2, stored as "./dataset/glcm/kernel3/non_tumor/BraTS2021_00020/original_glcm_Imc2.nrrd"
# Computed original_glcm_InverseVariance, stored as "./dataset/glcm/kernel3/non_tumor/BraTS2021_00020/original_glcm_InverseVariance.nrrd"
# ...
# Computed original_glcm_DifferenceEntropy, stored as "./dataset/glcm/kernel3/non_tumor/BraTS2021_00134/original_glcm_DifferenceEntropy.nrrd"
# Computed original_glcm_DifferenceVariance, stored as "./dataset/glcm/kernel3/non_tumor/BraTS2021_00134/original_glcm_DifferenceVariance.nrrd"
# Computed original_glcm_Id, stored as "./dataset/glcm/kernel3/non_tumor/BraTS2021_00134/original_glcm_Id.nrrd"
# Computed original_glcm_Idm, stored as "./dataset/glcm/kernel3/non_tumor/BraTS2021_00134/original_glcm_Idm.nrrd"
# Computed original_glcm_Idmn, stored as "./dataset/glcm/kernel3/non_tumor/BraTS2021_00134/original_glcm_Idmn.nrrd"
# Computed original_glcm_Idn, stored as "./dataset/glcm/kernel3/non_tumor/BraTS2021_00134/original_glcm_Idn.nrrd"
# Computed original_glcm_Imc1, stored as "./dataset/glcm/kernel3/non_tumor/BraTS2021_00134/original_glcm_Imc1.nrrd"
# Computed original_glcm_Imc2, stored as "./dataset/glcm/kernel3/non_tumor/BraTS2021_00134/original_glcm_Imc2.nrrd"
# Computed original_glcm_InverseVariance, stored as "./dataset/glcm/kernel3/non_tumor/BraTS2021_00134/original_glcm_InverseVariance.nrrd"
# Computed original_glcm_JointAverage, stored as "./dataset/glcm/kernel3/non_tumor/BraTS2021_00134/original_glcm_JointAverage.nrrd"
# Computed original_glcm_JointEnergy, stored as "./dataset/glcm/kernel3/non_tumor/BraTS2021_00134/original_glcm_JointEnergy.nrrd"
# Computed original_glcm_JointEntropy, stored as "./dataset/glcm/kernel3/non_tumor/BraTS2021_00134/original_glcm_JointEntropy.nrrd"
# Computed original_glcm_MCC, stored as "./dataset/glcm/kernel3/non_tumor/BraTS2021_00134/original_glcm_MCC.nrrd"
# Computed original_glcm_MaximumProbability, stored as "./dataset/glcm/kernel3/non_tumor/BraTS2021_00134/original_glcm_MaximumProbability.nrrd"
# Computed original_glcm_SumAverage, stored as "./dataset/glcm/kernel3/non_tumor/BraTS2021_00134/original_glcm_SumAverage.nrrd"
# Computed original_glcm_SumEntropy, stored as "./dataset/glcm/kernel3/non_tumor/BraTS2021_00134/original_glcm_SumEntropy.nrrd"
# Computed original_glcm_SumSquares, stored as "./dataset/glcm/kernel3/non_tumor/BraTS2021_00134/original_glcm_SumSquares.nrrd"
# Starting BraTS2021_00136
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# Computed original_glcm_Autocorrelation, stored as "./dataset/glcm/kernel3/non_tumor/BraTS2021_00136/original_glcm_Autocorrelation.nrrd"
# Computed original_glcm_ClusterProminence, stored as "./dataset/glcm/kernel3/non_tumor/BraTS2021_00136/original_glcm_ClusterProminence.nrrd"
# Computed original_glcm_ClusterShade, stored as "./dataset/glcm/kernel3/non_tumor/BraTS2021_00136/original_glcm_ClusterShade.nrrd"
# Computed original_glcm_ClusterTendency, stored as "./dataset/glcm/kernel3/non_tumor/BraTS2021_00136/original_glcm_ClusterTendency.nrrd"
# Computed original_glcm_Contrast, stored as "./dataset/glcm/kernel3/non_tumor/BraTS2021_00136/original_glcm_Contrast.nrrd"
# Computed original_glcm_Correlation, stored as "./dataset/glcm/kernel3/non_tumor/BraTS2021_00136/original_glcm_Correlation.nrrd"
# Computed original_glcm_DifferenceAverage, stored as "./dataset/glcm/kernel3/non_tumor/BraTS2021_00136/original_glcm_DifferenceAverage.nrrd"
# Computed original_glcm_DifferenceEntropy, stored as "./dataset/glcm/kernel3/non_tumor/BraTS2021_00136/original_glcm_DifferenceEntropy.nrrd"
# Computed original_glcm_DifferenceVariance, stored as "./dataset/glcm/kernel3/non_tumor/BraTS2021_00136/original_glcm_DifferenceVariance.nrrd"
# Computed original_glcm_Id, stored as "./dataset/glcm/kernel3/non_tumor/BraTS2021_00136/original_glcm_Id.nrrd"
# Computed original_glcm_Idm, stored as "./dataset/glcm/kernel3/non_tumor/BraTS2021_00136/original_glcm_Idm.nrrd"
# Computed original_glcm_Idmn, stored as "./dataset/glcm/kernel3/non_tumor/BraTS2021_00136/original_glcm_Idmn.nrrd"
# Computed original_glcm_Idn, stored as "./dataset/glcm/kernel3/non_tumor/BraTS2021_00136/original_glcm_Idn.nrrd"
# Computed original_glcm_Imc1, stored as "./dataset/glcm/kernel3/non_tumor/BraTS2021_00136/original_glcm_Imc1.nrrd"
# Computed original_glcm_Imc2, stored as "./dataset/glcm/kernel3/non_tumor/BraTS2021_00136/original_glcm_Imc2.nrrd"
# Computed original_glcm_InverseVariance, stored as "./dataset/glcm/kernel3/non_tumor/BraTS2021_00136/original_glcm_InverseVariance.nrrd"
# Computed original_glcm_JointAverage, stored as "./dataset/glcm/kernel3/non_tumor/BraTS2021_00136/original_glcm_JointAverage.nrrd"
# Computed original_glcm_JointEnergy, stored as "./dataset/glcm/kernel3/non_tumor/BraTS2021_00136/original_glcm_JointEnergy.nrrd"
# Computed original_glcm_JointEntropy, stored as "./dataset/glcm/kernel3/non_tumor/BraTS2021_00136/original_glcm_JointEntropy.nrrd"
# Computed original_glcm_MCC, stored as "./dataset/glcm/kernel3/non_tumor/BraTS2021_00136/original_glcm_MCC.nrrd"
# Computed original_glcm_MaximumProbability, stored as "./dataset/glcm/kernel3/non_tumor/BraTS2021_00136/original_glcm_MaximumProbability.nrrd"
# Computed original_glcm_SumAverage, stored as "./dataset/glcm/kernel3/non_tumor/BraTS2021_00136/original_glcm_SumAverage.nrrd"
# Computed original_glcm_SumEntropy, stored as "./dataset/glcm/kernel3/non_tumor/BraTS2021_00136/original_glcm_SumEntropy.nrrd"
# Computed original_glcm_SumSquares, stored as "./dataset/glcm/kernel3/non_tumor/BraTS2021_00136/original_glcm_SumSquares.nrrd"
# Starting BraTS2021_00137
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# Computed original_glcm_Autocorrelation, stored as "./dataset/glcm/kernel3/non_tumor/BraTS2021_00137/original_glcm_Autocorrelation.nrrd"
# Computed original_glcm_ClusterProminence, stored as "./dataset/glcm/kernel3/non_tumor/BraTS2021_00137/original_glcm_ClusterProminence.nrrd"
# Computed original_glcm_ClusterShade, stored as "./dataset/glcm/kernel3/non_tumor/BraTS2021_00137/original_glcm_ClusterShade.nrrd"
# Computed original_glcm_ClusterTendency, stored as "./dataset/glcm/kernel3/non_tumor/BraTS2021_00137/original_glcm_ClusterTendency.nrrd"
# Computed original_glcm_Contrast, stored as "./dataset/glcm/kernel3/non_tumor/BraTS2021_00137/original_glcm_Contrast.nrrd"
# Computed original_glcm_Correlation, stored as "./dataset/glcm/kernel3/non_tumor/BraTS2021_00137/original_glcm_Correlation.nrrd"
# Computed original_glcm_DifferenceAverage, stored as "./dataset/glcm/kernel3/non_tumor/BraTS2021_00137/original_glcm_DifferenceAverage.nrrd"
# Computed original_glcm_DifferenceEntropy, stored as "./dataset/glcm/kernel3/non_tumor/BraTS2021_00137/original_glcm_DifferenceEntropy.nrrd"
# Computed original_glcm_DifferenceVariance, stored as "./dataset/glcm/kernel3/non_tumor/BraTS2021_00137/original_glcm_DifferenceVariance.nrrd"
# Computed original_glcm_Id, stored as "./dataset/glcm/kernel3/non_tumor/BraTS2021_00137/original_glcm_Id.nrrd"
# Computed original_glcm_Idm, stored as "./dataset/glcm/kernel3/non_tumor/BraTS2021_00137/original_glcm_Idm.nrrd"
# Computed original_glcm_Idmn, stored as "./dataset/glcm/kernel3/non_tumor/BraTS2021_00137/original_glcm_Idmn.nrrd"
# Computed original_glcm_Idn, stored as "./dataset/glcm/kernel3/non_tumor/BraTS2021_00137/original_glcm_Idn.nrrd"
# Computed original_glcm_Imc1, stored as "./dataset/glcm/kernel3/non_tumor/BraTS2021_00137/original_glcm_Imc1.nrrd"
# Computed original_glcm_Imc2, stored as "./dataset/glcm/kernel3/non_tumor/BraTS2021_00137/original_glcm_Imc2.nrrd"
# Computed original_glcm_InverseVariance, stored as "./dataset/glcm/kernel3/non_tumor/BraTS2021_00137/original_glcm_InverseVariance.nrrd"
# Computed original_glcm_JointAverage, stored as "./dataset/glcm/kernel3/non_tumor/BraTS2021_00137/original_glcm_JointAverage.nrrd"
# Computed original_glcm_JointEnergy, stored as "./dataset/glcm/kernel3/non_tumor/BraTS2021_00137/original_glcm_JointEnergy.nrrd"
# Computed original_glcm_JointEntropy, stored as "./dataset/glcm/kernel3/non_tumor/BraTS2021_00137/original_glcm_JointEntropy.nrrd"
# Computed original_glcm_MCC, stored as "./dataset/glcm/kernel3/non_tumor/BraTS2021_00137/original_glcm_MCC.nrrd"
# Computed original_glcm_MaximumProbability, stored as "./dataset/glcm/kernel3/non_tumor/BraTS2021_00137/original_glcm_MaximumProbability.nrrd"
# Computed original_glcm_SumAverage, stored as "./dataset/glcm/kernel3/non_tumor/BraTS2021_00137/original_glcm_SumAverage.nrrd"
# Computed original_glcm_SumEntropy, stored as "./dataset/glcm/kernel3/non_tumor/BraTS2021_00137/original_glcm_SumEntropy.nrrd"
# Computed original_glcm_SumSquares, stored as "./dataset/glcm/kernel3/non_tumor/BraTS2021_00137/original_glcm_SumSquares.nrrd"
# Starting BraTS2021_00138
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# Computed original_glcm_Autocorrelation, stored as "./dataset/glcm/kernel3/non_tumor/BraTS2021_00138/original_glcm_Autocorrelation.nrrd"
# Computed original_glcm_ClusterProminence, stored as "./dataset/glcm/kernel3/non_tumor/BraTS2021_00138/original_glcm_ClusterProminence.nrrd"
# Computed original_glcm_ClusterShade, stored as "./dataset/glcm/kernel3/non_tumor/BraTS2021_00138/original_glcm_ClusterShade.nrrd"
# Computed original_glcm_ClusterTendency, stored as "./dataset/glcm/kernel3/non_tumor/BraTS2021_00138/original_glcm_ClusterTendency.nrrd"
# Computed original_glcm_Contrast, stored as "./dataset/glcm/kernel3/non_tumor/BraTS2021_00138/original_glcm_Contrast.nrrd"
# Computed original_glcm_Correlation, stored as "./dataset/glcm/kernel3/non_tumor/BraTS2021_00138/original_glcm_Correlation.nrrd"
# Computed original_glcm_DifferenceAverage, stored as "./dataset/glcm/kernel3/non_tumor/BraTS2021_00138/original_glcm_DifferenceAverage.nrrd"
# Computed original_glcm_DifferenceEntropy, stored as "./dataset/glcm/kernel3/non_tumor/BraTS2021_00138/original_glcm_DifferenceEntropy.nrrd"
# Computed original_glcm_DifferenceVariance, stored as "./dataset/glcm/kernel3/non_tumor/BraTS2021_00138/original_glcm_DifferenceVariance.nrrd"
# Computed original_glcm_Id, stored as "./dataset/glcm/kernel3/non_tumor/BraTS2021_00138/original_glcm_Id.nrrd"
# Computed original_glcm_Idm, stored as "./dataset/glcm/kernel3/non_tumor/BraTS2021_00138/original_glcm_Idm.nrrd"
# Computed original_glcm_Idmn, stored as "./dataset/glcm/kernel3/non_tumor/BraTS2021_00138/original_glcm_Idmn.nrrd"
# Computed original_glcm_Idn, stored as "./dataset/glcm/kernel3/non_tumor/BraTS2021_00138/original_glcm_Idn.nrrd"
# Computed original_glcm_Imc1, stored as "./dataset/glcm/kernel3/non_tumor/BraTS2021_00138/original_glcm_Imc1.nrrd"
# Computed original_glcm_Imc2, stored as "./dataset/glcm/kernel3/non_tumor/BraTS2021_00138/original_glcm_Imc2.nrrd"
# Computed original_glcm_InverseVariance, stored as "./dataset/glcm/kernel3/non_tumor/BraTS2021_00138/original_glcm_InverseVariance.nrrd"
# Computed original_glcm_JointAverage, stored as "./dataset/glcm/kernel3/non_tumor/BraTS2021_00138/original_glcm_JointAverage.nrrd"
# Computed original_glcm_JointEnergy, stored as "./dataset/glcm/kernel3/non_tumor/BraTS2021_00138/original_glcm_JointEnergy.nrrd"
# Computed original_glcm_JointEntropy, stored as "./dataset/glcm/kernel3/non_tumor/BraTS2021_00138/original_glcm_JointEntropy.nrrd"
# Computed original_glcm_MCC, stored as "./dataset/glcm/kernel3/non_tumor/BraTS2021_00138/original_glcm_MCC.nrrd"
# Computed original_glcm_MaximumProbability, stored as "./dataset/glcm/kernel3/non_tumor/BraTS2021_00138/original_glcm_MaximumProbability.nrrd"
# Computed original_glcm_SumAverage, stored as "./dataset/glcm/kernel3/non_tumor/BraTS2021_00138/original_glcm_SumAverage.nrrd"
# Computed original_glcm_SumEntropy, stored as "./dataset/glcm/kernel3/non_tumor/BraTS2021_00138/original_glcm_SumEntropy.nrrd"
# Computed original_glcm_SumSquares, stored as "./dataset/glcm/kernel3/non_tumor/BraTS2021_00138/original_glcm_SumSquares.nrrd"
# Starting BraTS2021_00139
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# Computed original_glcm_Autocorrelation, stored as "./dataset/glcm/kernel3/non_tumor/BraTS2021_00139/original_glcm_Autocorrelation.nrrd"
# Computed original_glcm_ClusterProminence, stored as "./dataset/glcm/kernel3/non_tumor/BraTS2021_00139/original_glcm_ClusterProminence.nrrd"
# Computed original_glcm_ClusterShade, stored as "./dataset/glcm/kernel3/non_tumor/BraTS2021_00139/original_glcm_ClusterShade.nrrd"
# Computed original_glcm_ClusterTendency, stored as "./dataset/glcm/kernel3/non_tumor/BraTS2021_00139/original_glcm_ClusterTendency.nrrd"
# Computed original_glcm_Contrast, stored as "./dataset/glcm/kernel3/non_tumor/BraTS2021_00139/original_glcm_Contrast.nrrd"
# Computed original_glcm_Correlation, stored as "./dataset/glcm/kernel3/non_tumor/BraTS2021_00139/original_glcm_Correlation.nrrd"
# Computed original_glcm_DifferenceAverage, stored as "./dataset/glcm/kernel3/non_tumor/BraTS2021_00139/original_glcm_DifferenceAverage.nrrd"
# Computed original_glcm_DifferenceEntropy, stored as "./dataset/glcm/kernel3/non_tumor/BraTS2021_00139/original_glcm_DifferenceEntropy.nrrd"
# Computed original_glcm_DifferenceVariance, stored as "./dataset/glcm/kernel3/non_tumor/BraTS2021_00139/original_glcm_DifferenceVariance.nrrd"
# Computed original_glcm_Id, stored as "./dataset/glcm/kernel3/non_tumor/BraTS2021_00139/original_glcm_Id.nrrd"
# Computed original_glcm_Idm, stored as "./dataset/glcm/kernel3/non_tumor/BraTS2021_00139/original_glcm_Idm.nrrd"
# Computed original_glcm_Idmn, stored as "./dataset/glcm/kernel3/non_tumor/BraTS2021_00139/original_glcm_Idmn.nrrd"
# Computed original_glcm_Idn, stored as "./dataset/glcm/kernel3/non_tumor/BraTS2021_00139/original_glcm_Idn.nrrd"
# Computed original_glcm_Imc1, stored as "./dataset/glcm/kernel3/non_tumor/BraTS2021_00139/original_glcm_Imc1.nrrd"
# Computed original_glcm_Imc2, stored as "./dataset/glcm/kernel3/non_tumor/BraTS2021_00139/original_glcm_Imc2.nrrd"
# Computed original_glcm_InverseVariance, stored as "./dataset/glcm/kernel3/non_tumor/BraTS2021_00139/original_glcm_InverseVariance.nrrd"
# Computed original_glcm_JointAverage, stored as "./dataset/glcm/kernel3/non_tumor/BraTS2021_00139/original_glcm_JointAverage.nrrd"
# Computed original_glcm_JointEnergy, stored as "./dataset/glcm/kernel3/non_tumor/BraTS2021_00139/original_glcm_JointEnergy.nrrd"
# Computed original_glcm_JointEntropy, stored as "./dataset/glcm/kernel3/non_tumor/BraTS2021_00139/original_glcm_JointEntropy.nrrd"
# Computed original_glcm_MCC, stored as "./dataset/glcm/kernel3/non_tumor/BraTS2021_00139/original_glcm_MCC.nrrd"
# Computed original_glcm_MaximumProbability, stored as "./dataset/glcm/kernel3/non_tumor/BraTS2021_00139/original_glcm_MaximumProbability.nrrd"
# Computed original_glcm_SumAverage, stored as "./dataset/glcm/kernel3/non_tumor/BraTS2021_00139/original_glcm_SumAverage.nrrd"
# Computed original_glcm_SumEntropy, stored as "./dataset/glcm/kernel3/non_tumor/BraTS2021_00139/original_glcm_SumEntropy.nrrd"
# Computed original_glcm_SumSquares, stored as "./dataset/glcm/kernel3/non_tumor/BraTS2021_00139/original_glcm_SumSquares.nrrd"
