# %%
# Import packages and modules
import numpy  as np
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow_decision_forests as tfdf

from sklearn.model_selection import train_test_split
# Out:
# 2026-09-06 15:10:08.411075: I tensorflow/core/util/port.cc:113] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2026-09-06 15:10:12.250791: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2026-09-06 15:10:31.318125: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
# Check the version of TensorFlow Decision Forests
print("Found TensorFlow Decision Forests v" + tfdf.__version__)
# Out:
# Found TensorFlow Decision Forests v1.9.1

# %%
# train/validation/test = 70/10/20
train_data = pd.read_csv("dataset/glcm/kernel3/dataset.train.csv")
validation_data = pd.read_csv("dataset/glcm/kernel3/dataset.validation.csv")
test_data = pd.read_csv("dataset/glcm/kernel3/dataset.test.csv")

# %%
from sklearn.utils.class_weight import compute_class_weight

# tinh class weight tren tap train
classes = np.array([0, 1])
weights = compute_class_weight(class_weight="balanced", classes=classes, y=train_data["label"])
class_weight = {0: weights[0], 1: weights[1]}

# gan sample_weight cho tung dong
train_data["sample_weight"] = train_data["label"].map(class_weight)
validation_data["sample_weight"] = validation_data["label"].map(class_weight)
test_data["sample_weight"] = test_data["label"].map(class_weight)

# Convert the dataset into a TensorFlow dataset.
train_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    train_data, label="label", weight="sample_weight"
)         
val_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    validation_data, label="label", weight="sample_weight"
)
test_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    test_data, label="label", weight="sample_weight"
)
# Out:
# 2026-09-06 15:11:12.588688: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:984] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2026-09-06 15:11:12.591073: W tensorflow/core/common_runtime/gpu/gpu_device.cc:2251] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...

# %%
import keras

# %%
# %%time

# Train a Gradient Boosted Trees model.
model = tfdf.keras.GradientBoostedTreesModel()

# Add evaluation metrics
model.compile(
    metrics=["accuracy"]
)
model.fit(x=train_ds)

# # Train a Gradient Boosted Trees model.
# model = tfdf.keras.GradientBoostedTreesModel(num_trees=1500)
# model.fit(train_ds)
# Out:
# Use /tmp/tmp59lp9axl as temporary training directory
# Reading training dataset...
# [WARNING 26-09-06 15:11:13.0139 UTC gradient_boosted_trees.cc:1840] "goss_alpha" set but "sampling_method" not equal to "GOSS".
# [WARNING 26-09-06 15:11:13.0179 UTC gradient_boosted_trees.cc:1851] "goss_beta" set but "sampling_method" not equal to "GOSS".
# [WARNING 26-09-06 15:11:13.0179 UTC gradient_boosted_trees.cc:1865] "selective_gradient_boosting_ratio" set but "sampling_method" not equal to "SELGB".
# Training dataset read in 0:00:05.310347. Found 311462 examples.
# Training model...
# Model trained in 0:01:40.310372
# Compiling model...
# [INFO 26-09-06 15:12:58.7319 UTC kernel.cc:1233] Loading model from path /tmp/tmp59lp9axl/model/ with prefix 229a9bd2e22848d1
# [INFO 26-09-06 15:12:58.7478 UTC quick_scorer_extended.cc:911] The binary was compiled without AVX2 support, but your CPU supports it. Enable it for faster model inference.
# [INFO 26-09-06 15:12:58.7488 UTC abstract_model.cc:1362] Engine "GradientBoostedTreesQuickScorerExtended" built
# [INFO 26-09-06 15:12:58.7488 UTC kernel.cc:1061] Use fast generic engine
# Model compiled.
# CPU times: user 16min 4s, sys: 6.42 s, total: 16min 10s
# Wall time: 1min 49s

# %%
# Evaluate the model
evaluate = model.evaluate(val_ds, return_dict=True)
print()

for name, value in evaluate.items():
    print(f"{name}: {value:.4f}")
# Out:
# WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 42/42 [==============================] - 4s 7ms/step - loss: 0.0000e+00 - accuracy: 0.6976
#
# loss: 0.0000
# accuracy: 0.6976

# %%
# Model Summary
model.summary()
# Out:
# Model: "gradient_boosted_trees_model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
# =================================================================
# Total params: 1 (1.00 Byte)
# Trainable params: 0 (0.00 Byte)
# Non-trainable params: 1 (1.00 Byte)
# _________________________________________________________________
# Type: "GRADIENT_BOOSTED_TREES"
# Task: CLASSIFICATION
# Label: "__LABEL"
#
# Input Features (24):
# 	Autocorrelation
# 	ClusterProminence
# 	ClusterShade
# 	ClusterTendency
# 	Contrast
# 	Correlation
# 	DifferenceAverage
# 	DifferenceEntropy
# 	DifferenceVariance
# 	Id
# 	Idm
# 	Idmn
# 	Idn
# 	Imc1
# 	Imc2
# 	InverseVariance
# 	JointAverage
# 	JointEnergy
# 	JointEntropy
# 	MCC
# 	MaximumProbability
# 	SumAverage
# 	SumEntropy
# 	SumSquares
#
# Trained with weights
#
# Variable Importance: INV_MEAN_MIN_DEPTH:
#     1.    "Autocorrelation"  0.232162 ################
#     2.               "Idmn"  0.213370 ##########
#     3.       "JointAverage"  0.212844 ##########
#     4.                "Idn"  0.207518 #########
#     5.         "SumAverage"  0.202658 #######
#     6.        "Correlation"  0.201048 #######
#     7.  "DifferenceAverage"  0.197737 ######
#     8.       "ClusterShade"  0.190657 ####
#     9.    "InverseVariance"  0.187649 ###
#    10.  "DifferenceEntropy"  0.186787 ###
#    11.           "Contrast"  0.184271 ##
#    12.                "MCC"  0.181641 ##
#    13.                "Idm"  0.181330 ##
#    14.         "SumEntropy"  0.181164 ##
#    15.                 "Id"  0.181115 ##
#    16. "DifferenceVariance"  0.180175 #
#    17.         "SumSquares"  0.176362
#    18. "MaximumProbability"  0.175985
#    19.    "ClusterTendency"  0.175401
#    20.  "ClusterProminence"  0.174889
#    21.       "JointEntropy"  0.174886
#    22.               "Imc1"  0.174610
#    23.               "Imc2"  0.174388
#    24.        "JointEnergy"  0.173537
#
# Variable Importance: NUM_AS_ROOT:
#     1.    "Autocorrelation" 62.000000 ################
#     2.       "JointAverage" 45.000000 ###########
#     3.         "SumAverage" 39.000000 #########
#     4.               "Idmn" 38.000000 #########
#     5.  "DifferenceAverage" 25.000000 ######
#     6.        "Correlation" 21.000000 #####
#     7.                "Idn" 19.000000 ####
#     8.    "InverseVariance"  9.000000 #
#     9.                 "Id"  8.000000 #
#    10.                "MCC"  8.000000 #
#    11.           "Contrast"  6.000000 #
#    12.         "SumEntropy"  6.000000 #
#    13.  "DifferenceEntropy"  5.000000
#    14.         "SumSquares"  3.000000
#    15.       "ClusterShade"  2.000000
#    16.    "ClusterTendency"  2.000000
#    17. "DifferenceVariance"  2.000000
#
# Variable Importance: NUM_NODES:
#     1.    "Autocorrelation" 884.000000 ################
#     2.                "Idn" 636.000000 ##########
#     3.               "Idmn" 635.000000 ##########
#     4.       "ClusterShade" 599.000000 #########
#     5.        "Correlation" 521.000000 ########
#     6.       "JointAverage" 470.000000 #######
#     7.         "SumAverage" 444.000000 ######
#     8.    "InverseVariance" 354.000000 ####
#     9.  "DifferenceEntropy" 311.000000 ###
#    10.  "DifferenceAverage" 310.000000 ###
#    11.                "MCC" 291.000000 ###
#    12. "DifferenceVariance" 256.000000 ##
#    13.                "Idm" 252.000000 ##
#    14.         "SumEntropy" 240.000000 ##
#    15.           "Contrast" 231.000000 ##
#    16. "MaximumProbability" 204.000000 #
#    17.                 "Id" 203.000000 #
#    18.  "ClusterProminence" 189.000000 #
#    19.         "SumSquares" 157.000000
#    20.               "Imc1" 143.000000
#    21.               "Imc2" 143.000000
#    22.       "JointEntropy" 143.000000
#    23.        "JointEnergy" 132.000000
#    24.    "ClusterTendency" 128.000000
#
# Variable Importance: SUM_SCORE:
#     1.    "Autocorrelation" 218525.253527 ################
#     2.        "Correlation" 19096.594238 #
#     3.                "Idn" 11078.860622
#     4.       "JointAverage" 10360.454259
#     5.               "Idmn" 7534.740798
#     6.         "SumAverage" 7069.327175
#     7. "DifferenceVariance" 6937.592162
#     8.    "InverseVariance" 6644.200227
#     9.  "DifferenceEntropy" 5706.904186
#    10.       "ClusterShade" 3752.573189
#    11.                 "Id" 3130.613818
#    12.                "Idm" 2736.470908
#    13.  "DifferenceAverage" 2570.263136
#    14. "MaximumProbability" 2139.146236
#    15.               "Imc1" 2058.902458
#    16.           "Contrast" 1793.052113
#    17.                "MCC" 1407.948731
#    18.        "JointEnergy" 1339.147929
#    19.         "SumEntropy" 1150.252761
#    20.       "JointEntropy" 623.281943
#    21.         "SumSquares" 581.112733
#    22.  "ClusterProminence" 567.869362
#    23.    "ClusterTendency" 507.663203
#    24.               "Imc2" 393.081944
#
#
#
# Loss: BINOMIAL_LOG_LIKELIHOOD
# Validation loss value: 0.326395
# Number of trees per iteration: 1
# Node format: NOT_SET
# Number of trees: 300
# Total number of nodes: 16052
#
# Number of nodes by tree:
# Count: 300 Average: 53.5067 StdDev: 8.24196
# Min: 29 Max: 63 Ignored: 0
# ----------------------------------------------
# [ 29, 30)  1   0.33%   0.33%
# [ 30, 32)  2   0.67%   1.00%
# [ 32, 34)  1   0.33%   1.33%
# [ 34, 36)  2   0.67%   2.00%
# [ 36, 37)  0   0.00%   2.00%
# [ 37, 39)  9   3.00%   5.00% ##
# [ 39, 41)  7   2.33%   7.33% #
# [ 41, 43)  9   3.00%  10.33% ##
# [ 43, 44) 14   4.67%  15.00% ##
# [ 44, 46) 11   3.67%  18.67% ##
# [ 46, 48) 21   7.00%  25.67% ####
# [ 48, 50) 31  10.33%  36.00% #####
# [ 50, 51)  0   0.00%  36.00%
# [ 51, 53) 20   6.67%  42.67% ###
# [ 53, 55) 13   4.33%  47.00% ##
# [ 55, 57) 15   5.00%  52.00% ###
# [ 57, 58) 29   9.67%  61.67% #####
# [ 58, 60) 21   7.00%  68.67% ####
# [ 60, 62) 34  11.33%  80.00% ######
# [ 62, 63] 60  20.00% 100.00% ##########
#
# Depth by leafs:
# Count: 8176 Average: 4.88197 StdDev: 0.445556
# Min: 2 Max: 5 Ignored: 0
# ----------------------------------------------
# [ 2, 3)   73   0.89%   0.89%
# [ 3, 4)  167   2.04%   2.94%
# [ 4, 5)  412   5.04%   7.97% #
# [ 5, 5] 7524  92.03% 100.00% ##########
#
# Number of training obs by leaf:
# Count: 8176 Average: 10281.8 StdDev: 31885.1
# Min: 5 Max: 273477 Ignored: 0
# ----------------------------------------------
# [      5,  13678) 7102  86.86%  86.86% ##########
# [  13678,  27352)  352   4.31%  91.17%
# [  27352,  41025)  168   2.05%  93.22%
# [  41025,  54699)  134   1.64%  94.86%
# [  54699,  68373)   73   0.89%  95.76%
# [  68373,  82046)   50   0.61%  96.37%
# [  82046,  95720)   39   0.48%  96.84%
# [  95720, 109394)   27   0.33%  97.17%
# [ 109394, 123067)   36   0.44%  97.61%
# [ 123067, 136741)   30   0.37%  97.98%
# [ 136741, 150415)   30   0.37%  98.35%
# [ 150415, 164088)   21   0.26%  98.61%
# [ 164088, 177762)   21   0.26%  98.86%
# [ 177762, 191436)   19   0.23%  99.09%
# [ 191436, 205109)   17   0.21%  99.30%
# [ 205109, 218783)   11   0.13%  99.44%
# [ 218783, 232457)   14   0.17%  99.61%
# [ 232457, 246130)   10   0.12%  99.73%
# [ 246130, 259804)    8   0.10%  99.83%
# [ 259804, 273477]   14   0.17% 100.00%
#
# Attribute in nodes:
# 	884 : Autocorrelation [NUMERICAL]
# 	636 : Idn [NUMERICAL]
# 	635 : Idmn [NUMERICAL]
# 	599 : ClusterShade [NUMERICAL]
# 	521 : Correlation [NUMERICAL]
# 	470 : JointAverage [NUMERICAL]
# 	444 : SumAverage [NUMERICAL]
# 	354 : InverseVariance [NUMERICAL]
# 	311 : DifferenceEntropy [NUMERICAL]
# 	310 : DifferenceAverage [NUMERICAL]
# 	291 : MCC [NUMERICAL]
# 	256 : DifferenceVariance [NUMERICAL]
# 	252 : Idm [NUMERICAL]
# 	240 : SumEntropy [NUMERICAL]
# 	231 : Contrast [NUMERICAL]
# 	204 : MaximumProbability [NUMERICAL]
# 	203 : Id [NUMERICAL]
# 	189 : ClusterProminence [NUMERICAL]
# 	157 : SumSquares [NUMERICAL]
# 	143 : JointEntropy [NUMERICAL]
# 	143 : Imc2 [NUMERICAL]
# 	143 : Imc1 [NUMERICAL]
# 	132 : JointEnergy [NUMERICAL]
# 	128 : ClusterTendency [NUMERICAL]
#
# Attribute in nodes with depth <= 0:
# 	62 : Autocorrelation [NUMERICAL]
# 	45 : JointAverage [NUMERICAL]
# 	39 : SumAverage [NUMERICAL]
# 	38 : Idmn [NUMERICAL]
# 	25 : DifferenceAverage [NUMERICAL]
# 	21 : Correlation [NUMERICAL]
# 	19 : Idn [NUMERICAL]
# 	9 : InverseVariance [NUMERICAL]
# 	8 : MCC [NUMERICAL]
# 	8 : Id [NUMERICAL]
# 	6 : SumEntropy [NUMERICAL]
# 	6 : Contrast [NUMERICAL]
# 	5 : DifferenceEntropy [NUMERICAL]
# 	3 : SumSquares [NUMERICAL]
# 	2 : DifferenceVariance [NUMERICAL]
# 	2 : ClusterTendency [NUMERICAL]
# 	2 : ClusterShade [NUMERICAL]
#
# Attribute in nodes with depth <= 1:
# 	125 : Autocorrelation [NUMERICAL]
# 	86 : Idmn [NUMERICAL]
# 	85 : JointAverage [NUMERICAL]
# 	72 : DifferenceAverage [NUMERICAL]
# 	68 : SumAverage [NUMERICAL]
# 	68 : Correlation [NUMERICAL]
# 	65 : Idn [NUMERICAL]
# 	44 : DifferenceEntropy [NUMERICAL]
# 	40 : Contrast [NUMERICAL]
# 	39 : ClusterShade [NUMERICAL]
# 	36 : InverseVariance [NUMERICAL]
# 	25 : Idm [NUMERICAL]
# 	24 : Id [NUMERICAL]
# 	22 : SumEntropy [NUMERICAL]
# 	22 : DifferenceVariance [NUMERICAL]
# 	20 : MCC [NUMERICAL]
# 	11 : ClusterTendency [NUMERICAL]
# 	10 : JointEntropy [NUMERICAL]
# 	9 : SumSquares [NUMERICAL]
# 	7 : ClusterProminence [NUMERICAL]
# 	6 : MaximumProbability [NUMERICAL]
# 	6 : Imc2 [NUMERICAL]
# 	5 : JointEnergy [NUMERICAL]
# 	5 : Imc1 [NUMERICAL]
#
# Attribute in nodes with depth <= 2:
# 	257 : Autocorrelation [NUMERICAL]
# 	183 : Idn [NUMERICAL]
# 	175 : Idmn [NUMERICAL]
# 	155 : JointAverage [NUMERICAL]
# 	153 : Correlation [NUMERICAL]
# 	127 : SumAverage [NUMERICAL]
# 	121 : DifferenceAverage [NUMERICAL]
# 	113 : ClusterShade [NUMERICAL]
# 	91 : DifferenceEntropy [NUMERICAL]
# 	82 : InverseVariance [NUMERICAL]
# 	75 : Contrast [NUMERICAL]
# 	68 : Idm [NUMERICAL]
# 	58 : SumEntropy [NUMERICAL]
# 	54 : MCC [NUMERICAL]
# 	52 : DifferenceVariance [NUMERICAL]
# 	51 : Id [NUMERICAL]
# 	47 : MaximumProbability [NUMERICAL]
# 	27 : SumSquares [NUMERICAL]
# 	27 : JointEntropy [NUMERICAL]
# 	25 : Imc1 [NUMERICAL]
# 	25 : ClusterTendency [NUMERICAL]
# 	24 : ClusterProminence [NUMERICAL]
# 	20 : Imc2 [NUMERICAL]
# 	17 : JointEnergy [NUMERICAL]
#
# Attribute in nodes with depth <= 3:
# 	484 : Autocorrelation [NUMERICAL]
# 	361 : Idn [NUMERICAL]
# 	326 : Idmn [NUMERICAL]
# 	287 : ClusterShade [NUMERICAL]
# 	281 : Correlation [NUMERICAL]
# 	280 : JointAverage [NUMERICAL]
# 	236 : SumAverage [NUMERICAL]
# 	197 : DifferenceAverage [NUMERICAL]
# 	193 : InverseVariance [NUMERICAL]
# 	172 : DifferenceEntropy [NUMERICAL]
# 	146 : Idm [NUMERICAL]
# 	129 : MCC [NUMERICAL]
# 	128 : DifferenceVariance [NUMERICAL]
# 	122 : SumEntropy [NUMERICAL]
# 	118 : Contrast [NUMERICAL]
# 	106 : Id [NUMERICAL]
# 	96 : MaximumProbability [NUMERICAL]
# 	77 : ClusterProminence [NUMERICAL]
# 	70 : Imc1 [NUMERICAL]
# 	66 : SumSquares [NUMERICAL]
# 	66 : JointEntropy [NUMERICAL]
# 	62 : Imc2 [NUMERICAL]
# 	60 : ClusterTendency [NUMERICAL]
# 	51 : JointEnergy [NUMERICAL]
#
# Attribute in nodes with depth <= 5:
# 	884 : Autocorrelation [NUMERICAL]
# 	636 : Idn [NUMERICAL]
# 	635 : Idmn [NUMERICAL]
# 	599 : ClusterShade [NUMERICAL]
# 	521 : Correlation [NUMERICAL]
# 	470 : JointAverage [NUMERICAL]
# 	444 : SumAverage [NUMERICAL]
# 	354 : InverseVariance [NUMERICAL]
# 	311 : DifferenceEntropy [NUMERICAL]
# 	310 : DifferenceAverage [NUMERICAL]
# 	291 : MCC [NUMERICAL]
# 	256 : DifferenceVariance [NUMERICAL]
# 	252 : Idm [NUMERICAL]
# 	240 : SumEntropy [NUMERICAL]
# 	231 : Contrast [NUMERICAL]
# 	204 : MaximumProbability [NUMERICAL]
# 	203 : Id [NUMERICAL]
# 	189 : ClusterProminence [NUMERICAL]
# 	157 : SumSquares [NUMERICAL]
# 	143 : JointEntropy [NUMERICAL]
# 	143 : Imc2 [NUMERICAL]
# 	143 : Imc1 [NUMERICAL]
# 	132 : JointEnergy [NUMERICAL]
# 	128 : ClusterTendency [NUMERICAL]
#
# Condition type in nodes:
# 	7876 : HigherCondition
# Condition type in nodes with depth <= 0:
# 	300 : HigherCondition
# Condition type in nodes with depth <= 1:
# 	900 : HigherCondition
# Condition type in nodes with depth <= 2:
# 	2027 : HigherCondition
# Condition type in nodes with depth <= 3:
# 	4114 : HigherCondition
# Condition type in nodes with depth <= 5:
# 	7876 : HigherCondition
#
# Training logs:
# Number of iteration to final model: 300
# 	Iter:1 train-loss:1.259217 valid-loss:1.260540  train-accuracy:0.887347 valid-accuracy:0.883013
# 	Iter:2 train-loss:1.154281 valid-loss:1.157305  train-accuracy:0.895723 valid-accuracy:0.890662
# 	Iter:3 train-loss:1.065329 valid-loss:1.069189  train-accuracy:0.899530 valid-accuracy:0.894115
# 	Iter:4 train-loss:0.990736 valid-loss:0.996200  train-accuracy:0.897524 valid-accuracy:0.891557
# 	Iter:5 train-loss:0.927362 valid-loss:0.933724  train-accuracy:0.900737 valid-accuracy:0.895480
# 	Iter:6 train-loss:0.872855 valid-loss:0.879877  train-accuracy:0.901526 valid-accuracy:0.896197
# 	Iter:16 train-loss:0.575714 valid-loss:0.589743  train-accuracy:0.910347 valid-accuracy:0.906735
# 	Iter:26 train-loss:0.466768 valid-loss:0.486811  train-accuracy:0.918994 valid-accuracy:0.913752
# 	Iter:36 train-loss:0.408132 valid-loss:0.433525  train-accuracy:0.928608 valid-accuracy:0.920694
# 	Iter:46 train-loss:0.372780 valid-loss:0.403749  train-accuracy:0.933878 valid-accuracy:0.924159
# 	Iter:56 train-loss:0.348278 valid-loss:0.384143  train-accuracy:0.937638 valid-accuracy:0.927037
# 	Iter:66 train-loss:0.329621 valid-loss:0.369532  train-accuracy:0.940501 valid-accuracy:0.928807
# 	Iter:76 train-loss:0.315622 valid-loss:0.359795  train-accuracy:0.942572 valid-accuracy:0.931810
# 	Iter:86 train-loss:0.305412 valid-loss:0.353660  train-accuracy:0.944387 valid-accuracy:0.932223
# 	Iter:96 train-loss:0.295983 valid-loss:0.349151  train-accuracy:0.945479 valid-accuracy:0.934115
# 	Iter:106 train-loss:0.288965 valid-loss:0.345588  train-accuracy:0.946959 valid-accuracy:0.934877
# 	Iter:116 train-loss:0.282539 valid-loss:0.342207  train-accuracy:0.948114 valid-accuracy:0.936142
# 	Iter:126 train-loss:0.277087 valid-loss:0.340585  train-accuracy:0.948829 valid-accuracy:0.936627
# 	Iter:136 train-loss:0.271830 valid-loss:0.339466  train-accuracy:0.949830 valid-accuracy:0.937755
# 	Iter:146 train-loss:0.267847 valid-loss:0.338145  train-accuracy:0.950358 valid-accuracy:0.937475
# 	Iter:156 train-loss:0.263616 valid-loss:0.335261  train-accuracy:0.951020 valid-accuracy:0.938064
# 	Iter:166 train-loss:0.259685 valid-loss:0.334644  train-accuracy:0.951732 valid-accuracy:0.937819
# 	Iter:176 train-loss:0.255846 valid-loss:0.333413  train-accuracy:0.952424 valid-accuracy:0.938234
# 	Iter:186 train-loss:0.252453 valid-loss:0.332718  train-accuracy:0.952725 valid-accuracy:0.938060
# 	Iter:196 train-loss:0.249499 valid-loss:0.331735  train-accuracy:0.953479 valid-accuracy:0.938128
# 	Iter:206 train-loss:0.246174 valid-loss:0.330996  train-accuracy:0.953901 valid-accuracy:0.937937
# 	Iter:216 train-loss:0.242619 valid-loss:0.330521  train-accuracy:0.954774 valid-accuracy:0.938458
# 	Iter:226 train-loss:0.239878 valid-loss:0.330054  train-accuracy:0.955162 valid-accuracy:0.939655
# 	Iter:236 train-loss:0.237489 valid-loss:0.329741  train-accuracy:0.955627 valid-accuracy:0.940556
# 	Iter:246 train-loss:0.234569 valid-loss:0.329041  train-accuracy:0.956326 valid-accuracy:0.938939
# 	Iter:256 train-loss:0.231938 valid-loss:0.328986  train-accuracy:0.956945 valid-accuracy:0.939252
# 	Iter:266 train-loss:0.228991 valid-loss:0.328628  train-accuracy:0.957862 valid-accuracy:0.938971
# 	Iter:276 train-loss:0.226869 valid-loss:0.327934  train-accuracy:0.958329 valid-accuracy:0.938694
# 	Iter:286 train-loss:0.223719 valid-loss:0.327097  train-accuracy:0.958861 valid-accuracy:0.938623
# 	Iter:296 train-loss:0.221178 valid-loss:0.326589  train-accuracy:0.959416 valid-accuracy:0.938483

# %%
# Model features
model.make_inspector().features()
# Out:
# ["Autocorrelation" (1; #0),
#  "ClusterProminence" (1; #1),
#  "ClusterShade" (1; #2),
#  "ClusterTendency" (1; #3),
#  "Contrast" (1; #4),
#  "Correlation" (1; #5),
#  "DifferenceAverage" (1; #6),
#  "DifferenceEntropy" (1; #7),
#  "DifferenceVariance" (1; #8),
#  "Id" (1; #9),
#  "Idm" (1; #10),
#  "Idmn" (1; #11),
#  "Idn" (1; #12),
#  "Imc1" (1; #13),
#  "Imc2" (1; #14),
#  "InverseVariance" (1; #15),
#  "JointAverage" (1; #16),
#  "JointEnergy" (1; #17),
#  "JointEntropy" (1; #18),
#  "MCC" (1; #19),
#  "MaximumProbability" (1; #20),
#  "SumAverage" (1; #21),
#  "SumEntropy" (1; #22),
#  "SumSquares" (1; #23)]

# %%
# Feature importance
model.make_inspector().variable_importances()
# Out:
# {'INV_MEAN_MIN_DEPTH': [("Autocorrelation" (1; #0), 0.23216247556690167),
#   ("Idmn" (1; #11), 0.2133697975558421),
#   ("JointAverage" (1; #16), 0.21284355930363316),
#   ("Idn" (1; #12), 0.20751775495755315),
#   ("SumAverage" (1; #21), 0.20265762260854742),
#   ("Correlation" (1; #5), 0.20104806657224278),
#   ("DifferenceAverage" (1; #6), 0.19773711436650712),
#   ("ClusterShade" (1; #2), 0.1906572222626423),
#   ("InverseVariance" (1; #15), 0.18764921649966415),
#   ("DifferenceEntropy" (1; #7), 0.18678743718722837),
#   ("Contrast" (1; #4), 0.1842710726393012),
#   ("MCC" (1; #19), 0.18164063804074),
#   ("Idm" (1; #10), 0.18133029013237048),
#   ("SumEntropy" (1; #22), 0.181164097019937),
#   ("Id" (1; #9), 0.1811149272143105),
#   ("DifferenceVariance" (1; #8), 0.18017491205166505),
#   ("SumSquares" (1; #23), 0.17636188970715516),
#   ("MaximumProbability" (1; #20), 0.17598532423862578),
#   ("ClusterTendency" (1; #3), 0.17540087999170062),
#   ("ClusterProminence" (1; #1), 0.17488917519353048),
#   ("JointEntropy" (1; #18), 0.1748858759420108),
#   ("Imc1" (1; #13), 0.17460955657573335),
#   ("Imc2" (1; #14), 0.17438762983926157),
#   ("JointEnergy" (1; #17), 0.17353726041673692)],
#  'SUM_SCORE': [("Autocorrelation" (1; #0), 218525.25352719036),
#   ("Correlation" (1; #5), 19096.594237524092),
#   ("Idn" (1; #12), 11078.860622489414),
#   ("JointAverage" (1; #16), 10360.454258776464),
#   ("Idmn" (1; #11), 7534.740797823808),
#   ("SumAverage" (1; #21), 7069.327174584812),
#   ("DifferenceVariance" (1; #8), 6937.592161891607),
#   ("InverseVariance" (1; #15), 6644.200227306607),
#   ("DifferenceEntropy" (1; #7), 5706.904185844738),
#   ("ClusterShade" (1; #2), 3752.573188764623),
#   ("Id" (1; #9), 3130.613818186461),
#   ("Idm" (1; #10), 2736.4709081834003),
#   ("DifferenceAverage" (1; #6), 2570.2631355735075),
#   ("MaximumProbability" (1; #20), 2139.146236492008),
#   ("Imc1" (1; #13), 2058.902458414898),
#   ("Contrast" (1; #4), 1793.0521127217826),
#   ("MCC" (1; #19), 1407.948731142233),
#   ("JointEnergy" (1; #17), 1339.1479288206324),
#   ("SumEntropy" (1; #22), 1150.2527608057471),
#   ("JointEntropy" (1; #18), 623.2819429899293),
#   ("SumSquares" (1; #23), 581.1127326769578),
#   ("ClusterProminence" (1; #1), 567.8693622671308),
#   ("ClusterTendency" (1; #3), 507.6632033388367),
#   ("Imc2" (1; #14), 393.08194410850376)],
#  'NUM_AS_ROOT': [("Autocorrelation" (1; #0), 62.0),
#   ("JointAverage" (1; #16), 45.0),
#   ("SumAverage" (1; #21), 39.0),
#   ("Idmn" (1; #11), 38.0),
#   ("DifferenceAverage" (1; #6), 25.0),
#   ("Correlation" (1; #5), 21.0),
#   ("Idn" (1; #12), 19.0),
#   ("InverseVariance" (1; #15), 9.0),
#   ("Id" (1; #9), 8.0),
#   ("MCC" (1; #19), 8.0),
#   ("Contrast" (1; #4), 6.0),
#   ("SumEntropy" (1; #22), 6.0),
#   ("DifferenceEntropy" (1; #7), 5.0),
#   ("SumSquares" (1; #23), 3.0),
#   ("ClusterShade" (1; #2), 2.0),
#   ("ClusterTendency" (1; #3), 2.0),
#   ("DifferenceVariance" (1; #8), 2.0)],
#  'NUM_NODES': [("Autocorrelation" (1; #0), 884.0),
#   ("Idn" (1; #12), 636.0),
#   ("Idmn" (1; #11), 635.0),
#   ("ClusterShade" (1; #2), 599.0),
#   ("Correlation" (1; #5), 521.0),
#   ("JointAverage" (1; #16), 470.0),
#   ("SumAverage" (1; #21), 444.0),
#   ("InverseVariance" (1; #15), 354.0),
#   ("DifferenceEntropy" (1; #7), 311.0),
#   ("DifferenceAverage" (1; #6), 310.0),
#   ("MCC" (1; #19), 291.0),
#   ("DifferenceVariance" (1; #8), 256.0),
#   ("Idm" (1; #10), 252.0),
#   ("SumEntropy" (1; #22), 240.0),
#   ("Contrast" (1; #4), 231.0),
#   ("MaximumProbability" (1; #20), 204.0),
#   ("Id" (1; #9), 203.0),
#   ("ClusterProminence" (1; #1), 189.0),
#   ("SumSquares" (1; #23), 157.0),
#   ("Imc1" (1; #13), 143.0),
#   ("Imc2" (1; #14), 143.0),
#   ("JointEntropy" (1; #18), 143.0),
#   ("JointEnergy" (1; #17), 132.0),
#   ("ClusterTendency" (1; #3), 128.0)]}

# %%
# Model self evaluation
model.make_inspector().evaluation()
# Out:
# Evaluation(num_examples=None, accuracy=0.9387602210044861, loss=0.32639506459236145, rmse=None, ndcg=None, aucs=None, auuc=None, qini=None)

# %%
logs = model.make_inspector().training_logs()

plt.figure(figsize=(12, 4))
plt.subplot(1, 2, 1)
plt.plot([log.num_trees for log in logs], [log.evaluation.accuracy for log in logs])
plt.xlabel("Number of trees")
plt.ylabel("Accuracy (out-of-bag)")
plt.subplot(1, 2, 2)
plt.plot([log.num_trees for log in logs], [log.evaluation.loss for log in logs])
plt.xlabel("Number of trees")
plt.ylabel("Logloss (out-of-bag)")
plt.show()

# %% [markdown]
# Calculate the score of our hold-out validation dataset

# %%
predictions = model.predict(val_ds)
y_true      = validation_data["label"]

from sklearn.metrics import roc_auc_score
ROC_AUC = roc_auc_score(y_true, predictions)
print("The ROC AUC score is %.5f" % ROC_AUC )
# Out:
# 42/42 [==============================] - 0s 6ms/step
# The ROC AUC score is 0.90854

# %%
# Compute binary classification metrics with sklearn
import numpy as np
from sklearn.metrics import (
    accuracy_score,
    precision_score,
    recall_score,
    f1_score,
    roc_auc_score,
    average_precision_score,
    confusion_matrix,
    classification_report,
    matthews_corrcoef,
    log_loss,
    brier_score_loss,
)

# Get predictions (probabilities or class labels)
preds = model.predict(test_ds)
# If model outputs probabilities, convert to labels by threshold 0.5
if preds.ndim == 2:
    # For TFDF classification, preds may be class probabilities with shape (N, 2)
    if preds.shape[1] == 2:
        pos_probs = preds[:, 1]
    else:
        # If single-probability column (positive class)
        pos_probs = preds[:, -1]
    y_pred = (pos_probs >= 0.5).astype(int)
else:
    # Already class labels
    y_pred = preds.astype(int)
    pos_probs = None

# Ground truth labels (must be 0/1 integers)
y_true = test_data["label"].astype(int).to_numpy()

# Core metrics
metrics = {}
metrics["accuracy"] = accuracy_score(y_true, y_pred)
metrics["precision"] = precision_score(y_true, y_pred, zero_division=0)
metrics["recall"] = recall_score(y_true, y_pred, zero_division=0)
metrics["f1"] = f1_score(y_true, y_pred, zero_division=0)
metrics["mcc"] = matthews_corrcoef(y_true, y_pred)

# Probabilistic metrics (only if we have probabilities)
if pos_probs is not None:
    metrics["roc_auc"] = roc_auc_score(y_true, pos_probs)
    metrics["pr_auc"] = average_precision_score(y_true, pos_probs)
    metrics["log_loss"] = log_loss(y_true, pos_probs, labels=[0,1])
    metrics["brier_score"] = brier_score_loss(y_true, pos_probs)

# Confusion matrix and detailed report
cm = confusion_matrix(y_true, y_pred, labels=[0,1])
report = classification_report(y_true, y_pred, digits=4)

print("Sklearn binary metrics:")
for k, v in metrics.items():
    print(f"{k}: {v:.4f}")
print("\nConfusion matrix:\n", cm)
print("\nClassification report:\n", report)
# Out:
# 83/83 [==============================] - 1s 6ms/step
# Sklearn binary metrics:
# accuracy: 0.8509
# precision: 0.3282
# recall: 0.6660
# f1: 0.4397
# mcc: 0.3955
# roc_auc: 0.8759
# pr_auc: 0.5745
# log_loss: 0.3355
# brier_score: 0.1062
#
# Confusion matrix:
#  [[65607  9913]
#  [ 2429  4843]]
#
# Classification report:
#                precision    recall  f1-score   support
#
#            0     0.9643    0.8687    0.9140     75520
#            1     0.3282    0.6660    0.4397      7272
#
#     accuracy                         0.8509     82792
#    macro avg     0.6463    0.7674    0.6769     82792
# weighted avg     0.9084    0.8509    0.8724     82792
