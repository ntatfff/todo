# %%
kernel = 5

# %%
import os
import pandas as pd

listDir = os.listdir(f'dataset/10p/firstorder/kernel{kernel}/non_tumor/')
listDir.sort()
for name in listDir:
  if name.startswith('BraTS2021_'):
    firstorderDf = pd.read_csv(f"dataset/10p/firstorder/kernel{kernel}/non_tumor/{name}/nrrd2csv.csv")
    glcmDf = pd.read_csv(f"dataset/10p/glcm/kernel{kernel}/non_tumor/{name}/nrrd2csv.csv")
    gldmDf = pd.read_csv(f"dataset/10p/gldm/kernel{kernel}/non_tumor/{name}/nrrd2csv.csv")
    glrlmDf = pd.read_csv(f"dataset/10p/glrlm/kernel{kernel}/non_tumor/{name}/nrrd2csv.csv")
    glszmDf = pd.read_csv(f"dataset/10p/glszm/kernel{kernel}/non_tumor/{name}/nrrd2csv.csv")
    ngtdmDf = pd.read_csv(f"dataset/10p/ngtdm/kernel{kernel}/non_tumor/{name}/nrrd2csv.csv")

    allDf = pd.concat([firstorderDf, glcmDf, gldmDf, glrlmDf, glszmDf, ngtdmDf], axis=1)
    os.makedirs(f"dataset/10p/all/kernel{kernel}/non_tumor/{name}", exist_ok=True)
    allDf.to_csv(f"dataset/10p/all/kernel{kernel}/non_tumor/{name}/nrrd2csv.csv", index=False)
print("Done")
# Out:
# Done

# %%
import os
import pandas as pd

listDir = os.listdir(f'dataset/10p/firstorder/kernel{kernel}/tumor/')
listDir.sort()
for name in listDir:
  if name.startswith('BraTS2021_'):
    firstorderDf = pd.read_csv(f"dataset/10p/firstorder/kernel{kernel}/tumor/{name}/nrrd2csv.csv")
    glcmDf = pd.read_csv(f"dataset/10p/glcm/kernel{kernel}/tumor/{name}/nrrd2csv.csv")
    gldmDf = pd.read_csv(f"dataset/10p/gldm/kernel{kernel}/tumor/{name}/nrrd2csv.csv")
    glrlmDf = pd.read_csv(f"dataset/10p/glrlm/kernel{kernel}/tumor/{name}/nrrd2csv.csv")
    glszmDf = pd.read_csv(f"dataset/10p/glszm/kernel{kernel}/tumor/{name}/nrrd2csv.csv")
    ngtdmDf = pd.read_csv(f"dataset/10p/ngtdm/kernel{kernel}/tumor/{name}/nrrd2csv.csv")

    allDf = pd.concat([firstorderDf, glcmDf, gldmDf, glrlmDf, glszmDf, ngtdmDf], axis=1)
    os.makedirs(f"dataset/10p/all/kernel{kernel}/tumor/{name}", exist_ok=True)
    allDf.to_csv(f"dataset/10p/all/kernel{kernel}/tumor/{name}/nrrd2csv.csv", index=False)
print("Done")
# Out:
# Done
