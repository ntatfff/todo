# %% [markdown]
# <a href="https://colab.research.google.com/github/ntatfff/todo/blob/202411241258/ColabRadiomicsFeatureExtractor.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
kernel = 1
className = 'firstorder'

# %%
# Parameters
kernel = 4
className = "firstorder"

# %%
import radiomics
import numpy as np
import SimpleITK as sitk
import radiomics.featureextractor
import os
import six
from os import path
import pandas as pd

def featureExtractor(fileId):
  imagePath = './dataset/BraTS2021_Training_Data/%s/%s_flair.nii.gz' % (fileId, fileId)
  image = sitk.ReadImage(imagePath)
  maskPath ='./dataset/BraTS2021_Training_Data/%s/%s_kernel%s_tumor.nii.gz' % (fileId, fileId, kernel)
  mask = sitk.ReadImage(maskPath)

  settings = {}
  settings['kernelRadius'] = kernel
  settings['maskedKernel'] = False
  settings['voxelBatch'] = 1000
  extractor = radiomics.featureextractor.RadiomicsFeatureExtractor(**settings)
  extractor.disableAllFeatures()
  extractor.enableFeatureClassByName(className)

  featureMap = extractor.execute(image, mask, voxelBased=True)

  for featureName, featureValue in six.iteritems(featureMap):
    if isinstance(featureValue, sitk.Image):
      fileFolder = './dataset/%s/kernel%s-radius%s/tumor/%s' % (className, kernel, kernel, fileId)
      if path.exists(fileFolder) == False:
        os.makedirs(fileFolder, exist_ok=True)
      sitk.WriteImage(featureValue, '%s/%s.nrrd' % (fileFolder, featureName))
      print('Computed %s, stored as "%s/%s.nrrd"' % (featureName, fileFolder, featureName))
    # else:
    #   print('%s: %s' % (featureName, featureValue))

monitorFilePath = './dataset/%s/kernel%s-radius%s/tumor.monitor.csv' % (className, kernel, kernel)
monitor = pd.read_csv(monitorFilePath, index_col='no')
for i, row in monitor.iterrows():
  if row['done'] != 0:
    continue
  fileId = row['file']
  print('Starting %s' % (fileId))
  featureExtractor(fileId)
  monitor.at[i, 'done'] = 1
  monitor.to_csv(monitorFilePath)
# Out:
# Starting BraTS2021_00002
# Computed original_firstorder_10Percentile, stored as "./dataset/firstorder/kernel4-radius4/tumor/BraTS2021_00002/original_firstorder_10Percentile.nrrd"
# Computed original_firstorder_90Percentile, stored as "./dataset/firstorder/kernel4-radius4/tumor/BraTS2021_00002/original_firstorder_90Percentile.nrrd"
# Computed original_firstorder_Energy, stored as "./dataset/firstorder/kernel4-radius4/tumor/BraTS2021_00002/original_firstorder_Energy.nrrd"
# Computed original_firstorder_Entropy, stored as "./dataset/firstorder/kernel4-radius4/tumor/BraTS2021_00002/original_firstorder_Entropy.nrrd"
# Computed original_firstorder_InterquartileRange, stored as "./dataset/firstorder/kernel4-radius4/tumor/BraTS2021_00002/original_firstorder_InterquartileRange.nrrd"
# Computed original_firstorder_Kurtosis, stored as "./dataset/firstorder/kernel4-radius4/tumor/BraTS2021_00002/original_firstorder_Kurtosis.nrrd"
# Computed original_firstorder_Maximum, stored as "./dataset/firstorder/kernel4-radius4/tumor/BraTS2021_00002/original_firstorder_Maximum.nrrd"
# Computed original_firstorder_MeanAbsoluteDeviation, stored as "./dataset/firstorder/kernel4-radius4/tumor/BraTS2021_00002/original_firstorder_MeanAbsoluteDeviation.nrrd"
# Computed original_firstorder_Mean, stored as "./dataset/firstorder/kernel4-radius4/tumor/BraTS2021_00002/original_firstorder_Mean.nrrd"
# Computed original_firstorder_Median, stored as "./dataset/firstorder/kernel4-radius4/tumor/BraTS2021_00002/original_firstorder_Median.nrrd"
# Computed original_firstorder_Minimum, stored as "./dataset/firstorder/kernel4-radius4/tumor/BraTS2021_00002/original_firstorder_Minimum.nrrd"
# Computed original_firstorder_Range, stored as "./dataset/firstorder/kernel4-radius4/tumor/BraTS2021_00002/original_firstorder_Range.nrrd"
# Computed original_firstorder_RobustMeanAbsoluteDeviation, stored as "./dataset/firstorder/kernel4-radius4/tumor/BraTS2021_00002/original_firstorder_RobustMeanAbsoluteDeviation.nrrd"
# Computed original_firstorder_RootMeanSquared, stored as "./dataset/firstorder/kernel4-radius4/tumor/BraTS2021_00002/original_firstorder_RootMeanSquared.nrrd"
# Computed original_firstorder_Skewness, stored as "./dataset/firstorder/kernel4-radius4/tumor/BraTS2021_00002/original_firstorder_Skewness.nrrd"
# Computed original_firstorder_TotalEnergy, stored as "./dataset/firstorder/kernel4-radius4/tumor/BraTS2021_00002/original_firstorder_TotalEnergy.nrrd"
# Computed original_firstorder_Uniformity, stored as "./dataset/firstorder/kernel4-radius4/tumor/BraTS2021_00002/original_firstorder_Uniformity.nrrd"
# Computed original_firstorder_Variance, stored as "./dataset/firstorder/kernel4-radius4/tumor/BraTS2021_00002/original_firstorder_Variance.nrrd"
