# %%
# %pip install -q tensorflow_decision_forests

# %%
# Import packages and modules
import numpy  as np
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow_decision_forests as tfdf

from sklearn.model_selection import train_test_split

# %%
# Check the version of TensorFlow Decision Forests
print("Found TensorFlow Decision Forests v" + tfdf.__version__)
# Out:
# Found TensorFlow Decision Forests v1.12.0

# %%
# train/validation = 80/20
dataset = pd.read_csv('dataset/kernel5-radius5/dataset.csv')
train_data, validation_data = train_test_split(
    dataset, test_size=0.2, random_state=42
)

# %%
# Convert the dataset into a TensorFlow dataset.
train_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    train_data, label="label"
)         
val_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    validation_data, label="label"
)

# %%
import keras

# %%
# %%time

# Train a Random Forest model.
model = tfdf.keras.RandomForestModel()

# Add evaluation metrics
model.compile(
    metrics=["accuracy"]
)
model.fit(x=train_ds)

# # Train a Gradient Boosted Trees model.
# model = tfdf.keras.GradientBoostedTreesModel(num_trees=1500)
# model.fit(train_ds)
# Out:
# Use /tmp/tmpa9ox5t7z as temporary training directory
# Reading training dataset...
# Reading training dataset...
# Training dataset read in 0:00:00.631842. Found 89956 examples.
# Training model...
# Training dataset read in 0:00:00.631842. Found 89956 examples.
# Training model...
# I0000 00:00:1765646310.249233   18900 kernel.cc:782] Start Yggdrasil model training
# I0000 00:00:1765646310.249285   18900 kernel.cc:783] Collect training examples
# I0000 00:00:1765646310.249294   18900 kernel.cc:795] Dataspec guide:
# column_guides {
#   column_name_pattern: "^__LABEL$"
#   type: CATEGORICAL
#   categorial {
#     min_vocab_frequency: 0
#     max_vocab_count: -1
#   }
# }
# default_column_guide {
#   categorial {
#     max_vocab_count: 2000
#   }
#   discretized_numerical {
#     maximum_num_bins: 255
#   }
# }
# ignore_columns_without_guides: false
# detect_numerical_as_discretized_numerical: false
#
# I0000 00:00:1765646310.249446   18900 kernel.cc:401] Number of batches: 90
# I0000 00:00:1765646310.249452   18900 kernel.cc:402] Number of examples: 89956
# I0000 00:00:1765646310.255075   18900 kernel.cc:802] Training dataset:
# Number of records: 89956
# Number of columns: 19
#
# Number of columns by type:
# 	NUMERICAL: 18 (94.7368%)
# 	CATEGORICAL: 1 (5.26316%)
#
# Columns:
#
# NUMERICAL: 18 (94.7368%)
# 	0: "10Percentile" NUMERICAL mean:492.159 min:0 max:3308 sd:454.761
# 	1: "90Percentile" NUMERICAL mean:1049.98 min:27 max:4036 sd:631.691
# 	2: "Energy" NUMERICAL mean:1.27286e+09 min:448753 max:1.7256e+10 sd:1.39371e+09
# 	3: "Entropy" NUMERICAL mean:4.01987 min:0.0741954 max:7.05046 sd:1.2956
# 	4: "InterquartileRange" NUMERICAL mean:331.6 min:6 max:3191.5 sd:360.654
# 	5: "Kurtosis" NUMERICAL mean:4.2369 min:1.00928 max:223.602 sd:4.05688
# 	6: "Maximum" NUMERICAL mean:1267.5 min:42 max:5142 sd:751.879
# 	7: "Mean" NUMERICAL mean:786.8 min:9.73028 max:3577.68 sd:501.299
# 	8: "MeanAbsoluteDeviation" NUMERICAL mean:185.157 min:3.54697 max:1367.23 sd:168.42
# 	9: "Median" NUMERICAL mean:805.045 min:0 max:3719 sd:528.535
# 	10: "Minimum" NUMERICAL mean:231.439 min:0 max:3124 sd:316.353
# 	11: "Range" NUMERICAL mean:1036.06 min:26 max:4841 sd:681.782
# 	12: "RobustMeanAbsoluteDeviation" NUMERICAL mean:145.372 min:2.5102 max:1352.18 sd:154.522
# 	13: "RootMeanSquared" NUMERICAL mean:834.237 min:18.3618 max:3600.65 sd:510.259
# 	14: "Skewness" NUMERICAL mean:-0.458084 min:-10.8932 max:6.89468 sd:1.00955
# 	15: "TotalEnergy" NUMERICAL mean:1.27286e+09 min:448753 max:1.7256e+10 sd:1.39371e+09
# 	16: "Uniformity" NUMERICAL mean:0.128893 min:0.00865959 max:0.982131 sd:0.130467
# 	17: "Variance" NUMERICAL mean:85962 min:19.4266 max:2.09104e+06 sd:134696
#
# CATEGORICAL: 1 (5.26316%)
# 	18: "__LABEL" CATEGORICAL integerized vocab-size:3 no-ood-item
#
# Terminology:
# 	nas: Number of non-available (i.e. missing) values.
# 	ood: Out of dictionary.
# 	manually-defined: Attribute whose type is manually defined by the user, i.e., the type was not automatically inferred.
# 	tokenized: The attribute value is obtained through tokenization.
# 	has-dict: The attribute is attached to a string dictionary e.g. a categorical attribute stored as a string.
# 	vocab-size: Number of unique values.
#
# I0000 00:00:1765646310.255122   18900 kernel.cc:818] Configure learner
# I0000 00:00:1765646310.255239   18900 kernel.cc:831] Training config:
# learner: "RANDOM_FOREST"
# features: "^10Percentile$"
# features: "^90Percentile$"
# features: "^Energy$"
# features: "^Entropy$"
# features: "^InterquartileRange$"
# features: "^Kurtosis$"
# features: "^Maximum$"
# features: "^Mean$"
# features: "^MeanAbsoluteDeviation$"
# features: "^Median$"
# features: "^Minimum$"
# features: "^Range$"
# features: "^RobustMeanAbsoluteDeviation$"
# features: "^RootMeanSquared$"
# features: "^Skewness$"
# features: "^TotalEnergy$"
# features: "^Uniformity$"
# features: "^Variance$"
# label: "^__LABEL$"
# task: CLASSIFICATION
# random_seed: 123456
# metadata {
#   framework: "TF Keras"
# }
# pure_serving_model: false
# [yggdrasil_decision_forests.model.random_forest.proto.random_forest_config] {
#   num_trees: 300
#   decision_tree {
#     max_depth: 16
#     min_examples: 5
#     in_split_min_examples_check: true
#     keep_non_leaf_label_distribution: true
#     num_candidate_attributes: 0
#     missing_value_policy: GLOBAL_IMPUTATION
#     allow_na_conditions: false
#     categorical_set_greedy_forward {
#       sampling: 0.1
#       max_num_items: -1
#       min_item_frequency: 1
#     }
#     growing_strategy_local {
#     }
#     categorical {
#       cart {
#       }
#     }
#     axis_aligned_split {
#     }
#     internal {
#       sorting_strategy: PRESORTED
#     }
#     uplift {
#       min_examples_in_treatment: 5
#       split_score: KULLBACK_LEIBLER
#     }
#     numerical_vector_sequence {
#       max_num_test_examples: 1000
#       num_random_selected_anchors: 100
#     }
#   }
#   winner_take_all_inference: true
#   compute_oob_performances: true
#   compute_oob_variable_importances: false
#   num_oob_variable_importances_permutations: 1
#   bootstrap_training_dataset: true
#   bootstrap_size_ratio: 1
#   adapt_bootstrap_size_ratio_for_maximum_training_duration: false
#   sampling_with_replacement: true
# }
#
# I0000 00:00:1765646310.255385   18900 kernel.cc:834] Deployment config:
# cache_path: "/tmp/tmpa9ox5t7z/working_cache"
# num_threads: 12
# try_resume_training: true
#
# I0000 00:00:1765646310.255535   26934 kernel.cc:895] Train model
# I0000 00:00:1765646310.255675   26934 random_forest.cc:438] Training random forest on 89956 example(s) and 18 feature(s).
# I0000 00:00:1765646310.271899   26934 gpu.cc:93] Cannot initialize GPU: Not compiled with GPU support
# I0000 00:00:1765646310.572868   26951 random_forest.cc:865] Train tree 1/300 accuracy:0.947539 logloss:1.89089 [index:5 total:0.30s tree:0.30s]
# I0000 00:00:1765646310.659033   26952 random_forest.cc:865] Train tree 11/300 accuracy:0.955599 logloss:0.976027 [index:6 total:0.38s tree:0.38s]
# I0000 00:00:1765646310.572868   26951 random_forest.cc:865] Train tree 1/300 accuracy:0.947539 logloss:1.89089 [index:5 total:0.30s tree:0.30s]
# I0000 00:00:1765646310.659033   26952 random_forest.cc:865] Train tree 11/300 accuracy:0.955599 logloss:0.976027 [index:6 total:0.38s tree:0.38s]
# I0000 00:00:1765646310.965635   26948 random_forest.cc:865] Train tree 21/300 accuracy:0.957022 logloss:0.725098 [index:21 total:0.69s tree:0.32s]
# I0000 00:00:1765646310.965635   26948 random_forest.cc:865] Train tree 21/300 accuracy:0.957022 logloss:0.725098 [index:21 total:0.69s tree:0.32s]
# I0000 00:00:1765646311.326096   26958 random_forest.cc:865] Train tree 31/300 accuracy:0.957312 logloss:0.621733 [index:30 total:1.05s tree:0.38s]
# I0000 00:00:1765646311.326096   26958 random_forest.cc:865] Train tree 31/300 accuracy:0.957312 logloss:0.621733 [index:30 total:1.05s tree:0.38s]
# I0000 00:00:1765646311.640087   26950 random_forest.cc:865] Train tree 41/300 accuracy:0.957724 logloss:0.550653 [index:41 total:1.37s tree:0.33s]
# I0000 00:00:1765646311.640087   26950 random_forest.cc:865] Train tree 41/300 accuracy:0.957724 logloss:0.550653 [index:41 total:1.37s tree:0.33s]
# I0000 00:00:1765646311.906564   26956 random_forest.cc:865] Train tree 51/300 accuracy:0.958124 logloss:0.505946 [index:50 total:1.63s tree:0.32s]
# I0000 00:00:1765646311.906564   26956 random_forest.cc:865] Train tree 51/300 accuracy:0.958124 logloss:0.505946 [index:50 total:1.63s tree:0.32s]
# I0000 00:00:1765646312.192094   26947 random_forest.cc:865] Train tree 61/300 accuracy:0.958502 logloss:0.47039 [index:60 total:1.92s tree:0.31s]
# I0000 00:00:1765646312.192094   26947 random_forest.cc:865] Train tree 61/300 accuracy:0.958502 logloss:0.47039 [index:60 total:1.92s tree:0.31s]
# I0000 00:00:1765646312.403616   26955 random_forest.cc:865] Train tree 71/300 accuracy:0.958569 logloss:0.441315 [index:70 total:2.13s tree:0.34s]
# I0000 00:00:1765646312.403616   26955 random_forest.cc:865] Train tree 71/300 accuracy:0.958569 logloss:0.441315 [index:70 total:2.13s tree:0.34s]
# I0000 00:00:1765646312.738048   26949 random_forest.cc:865] Train tree 81/300 accuracy:0.958746 logloss:0.418227 [index:80 total:2.46s tree:0.39s]
# I0000 00:00:1765646312.738048   26949 random_forest.cc:865] Train tree 81/300 accuracy:0.958746 logloss:0.418227 [index:80 total:2.46s tree:0.39s]
# I0000 00:00:1765646312.995660   26952 random_forest.cc:865] Train tree 91/300 accuracy:0.958913 logloss:0.40135 [index:91 total:2.72s tree:0.32s]
# I0000 00:00:1765646312.995660   26952 random_forest.cc:865] Train tree 91/300 accuracy:0.958913 logloss:0.40135 [index:91 total:2.72s tree:0.32s]
# I0000 00:00:1765646313.284374   26951 random_forest.cc:865] Train tree 101/300 accuracy:0.958835 logloss:0.383772 [index:99 total:3.01s tree:0.35s]
# I0000 00:00:1765646313.284374   26951 random_forest.cc:865] Train tree 101/300 accuracy:0.958835 logloss:0.383772 [index:99 total:3.01s tree:0.35s]
# I0000 00:00:1765646313.557313   26957 random_forest.cc:865] Train tree 111/300 accuracy:0.958791 logloss:0.366531 [index:109 total:3.28s tree:0.38s]
# I0000 00:00:1765646313.557313   26957 random_forest.cc:865] Train tree 111/300 accuracy:0.958791 logloss:0.366531 [index:109 total:3.28s tree:0.38s]
# I0000 00:00:1765646313.855827   26956 random_forest.cc:865] Train tree 121/300 accuracy:0.959013 logloss:0.358459 [index:119 total:3.58s tree:0.34s]
# I0000 00:00:1765646313.855827   26956 random_forest.cc:865] Train tree 121/300 accuracy:0.959013 logloss:0.358459 [index:119 total:3.58s tree:0.34s]
# I0000 00:00:1765646314.155463   26955 random_forest.cc:865] Train tree 131/300 accuracy:0.959047 logloss:0.34846 [index:130 total:3.88s tree:0.34s]
# I0000 00:00:1765646314.155463   26955 random_forest.cc:865] Train tree 131/300 accuracy:0.959047 logloss:0.34846 [index:130 total:3.88s tree:0.34s]
# I0000 00:00:1765646314.396438   26949 random_forest.cc:865] Train tree 141/300 accuracy:0.959191 logloss:0.337069 [index:140 total:4.12s tree:0.33s]
# I0000 00:00:1765646314.396438   26949 random_forest.cc:865] Train tree 141/300 accuracy:0.959191 logloss:0.337069 [index:140 total:4.12s tree:0.33s]
# I0000 00:00:1765646314.607215   26952 random_forest.cc:865] Train tree 151/300 accuracy:0.95898 logloss:0.329822 [index:150 total:4.33s tree:0.31s]
# I0000 00:00:1765646314.607215   26952 random_forest.cc:865] Train tree 151/300 accuracy:0.95898 logloss:0.329822 [index:150 total:4.33s tree:0.31s]
# I0000 00:00:1765646314.892585   26951 random_forest.cc:865] Train tree 161/300 accuracy:0.959124 logloss:0.320925 [index:160 total:4.62s tree:0.32s]
# I0000 00:00:1765646314.892585   26951 random_forest.cc:865] Train tree 161/300 accuracy:0.959124 logloss:0.320925 [index:160 total:4.62s tree:0.32s]
# I0000 00:00:1765646315.207487   26951 random_forest.cc:865] Train tree 171/300 accuracy:0.959169 logloss:0.312721 [index:172 total:4.93s tree:0.31s]
# I0000 00:00:1765646315.207487   26951 random_forest.cc:865] Train tree 171/300 accuracy:0.959169 logloss:0.312721 [index:172 total:4.93s tree:0.31s]
# I0000 00:00:1765646315.520491   26957 random_forest.cc:865] Train tree 181/300 accuracy:0.959102 logloss:0.307475 [index:180 total:5.25s tree:0.34s]
# I0000 00:00:1765646315.520491   26957 random_forest.cc:865] Train tree 181/300 accuracy:0.959102 logloss:0.307475 [index:180 total:5.25s tree:0.34s]
# I0000 00:00:1765646315.794922   26948 random_forest.cc:865] Train tree 191/300 accuracy:0.95918 logloss:0.303724 [index:189 total:5.52s tree:0.34s]
# I0000 00:00:1765646315.794922   26948 random_forest.cc:865] Train tree 191/300 accuracy:0.95918 logloss:0.303724 [index:189 total:5.52s tree:0.34s]
# I0000 00:00:1765646316.110814   26956 random_forest.cc:865] Train tree 201/300 accuracy:0.959024 logloss:0.299145 [index:201 total:5.84s tree:0.34s]
# I0000 00:00:1765646316.283296   26955 random_forest.cc:865] Train tree 211/300 accuracy:0.959024 logloss:0.294978 [index:210 total:6.01s tree:0.33s]
# I0000 00:00:1765646316.110814   26956 random_forest.cc:865] Train tree 201/300 accuracy:0.959024 logloss:0.299145 [index:201 total:5.84s tree:0.34s]
# I0000 00:00:1765646316.283296   26955 random_forest.cc:865] Train tree 211/300 accuracy:0.959024 logloss:0.294978 [index:210 total:6.01s tree:0.33s]
# I0000 00:00:1765646316.593871   26947 random_forest.cc:865] Train tree 221/300 accuracy:0.958958 logloss:0.288626 [index:218 total:6.32s tree:0.39s]
# I0000 00:00:1765646316.593871   26947 random_forest.cc:865] Train tree 221/300 accuracy:0.958958 logloss:0.288626 [index:218 total:6.32s tree:0.39s]
# I0000 00:00:1765646316.902575   26953 random_forest.cc:865] Train tree 231/300 accuracy:0.959036 logloss:0.28511 [index:231 total:6.63s tree:0.33s]
# I0000 00:00:1765646316.902575   26953 random_forest.cc:865] Train tree 231/300 accuracy:0.959036 logloss:0.28511 [index:231 total:6.63s tree:0.33s]
# I0000 00:00:1765646317.232995   26951 random_forest.cc:865] Train tree 241/300 accuracy:0.959102 logloss:0.278889 [index:240 total:6.96s tree:0.36s]
# I0000 00:00:1765646317.232995   26951 random_forest.cc:865] Train tree 241/300 accuracy:0.959102 logloss:0.278889 [index:240 total:6.96s tree:0.36s]
# I0000 00:00:1765646318.662222   26958 random_forest.cc:865] Train tree 251/300 accuracy:0.959213 logloss:0.276107 [index:250 total:8.39s tree:1.48s]
# I0000 00:00:1765646318.662222   26958 random_forest.cc:865] Train tree 251/300 accuracy:0.959213 logloss:0.276107 [index:250 total:8.39s tree:1.48s]
# I0000 00:00:1765646320.828100   26956 random_forest.cc:865] Train tree 261/300 accuracy:0.959136 logloss:0.273 [index:260 total:10.55s tree:2.26s]
# I0000 00:00:1765646320.828100   26956 random_forest.cc:865] Train tree 261/300 accuracy:0.959136 logloss:0.273 [index:260 total:10.55s tree:2.26s]
# I0000 00:00:1765646321.162765   26956 random_forest.cc:865] Train tree 271/300 accuracy:0.959024 logloss:0.269893 [index:272 total:10.89s tree:0.33s]
# I0000 00:00:1765646321.162765   26956 random_forest.cc:865] Train tree 271/300 accuracy:0.959024 logloss:0.269893 [index:272 total:10.89s tree:0.33s]
# I0000 00:00:1765646321.413567   26949 random_forest.cc:865] Train tree 281/300 accuracy:0.95918 logloss:0.266027 [index:280 total:11.14s tree:0.38s]
# I0000 00:00:1765646321.413567   26949 random_forest.cc:865] Train tree 281/300 accuracy:0.95918 logloss:0.266027 [index:280 total:11.14s tree:0.38s]
# I0000 00:00:1765646321.674262   26954 random_forest.cc:865] Train tree 291/300 accuracy:0.959058 logloss:0.261136 [index:290 total:11.40s tree:0.34s]
# I0000 00:00:1765646321.674262   26954 random_forest.cc:865] Train tree 291/300 accuracy:0.959058 logloss:0.261136 [index:290 total:11.40s tree:0.34s]
# I0000 00:00:1765646321.907508   26951 random_forest.cc:865] Train tree 300/300 accuracy:0.959158 logloss:0.257968 [index:298 total:11.63s tree:0.30s]
# I0000 00:00:1765646321.907760   26934 random_forest.cc:949] Final OOB metrics: accuracy:0.959158 logloss:0.257968
# I0000 00:00:1765646322.078892   26934 kernel.cc:926] Export model in log directory: /tmp/tmpa9ox5t7z with prefix a378558beac94606
# I0000 00:00:1765646321.907508   26951 random_forest.cc:865] Train tree 300/300 accuracy:0.959158 logloss:0.257968 [index:298 total:11.63s tree:0.30s]
# I0000 00:00:1765646321.907760   26934 random_forest.cc:949] Final OOB metrics: accuracy:0.959158 logloss:0.257968
# I0000 00:00:1765646322.078892   26934 kernel.cc:926] Export model in log directory: /tmp/tmpa9ox5t7z with prefix a378558beac94606
# I0000 00:00:1765646322.435171   26934 kernel.cc:944] Save model in resources
# I0000 00:00:1765646322.437499   18900 abstract_model.cc:921] Model self evaluation:
# Number of predictions (without weights): 89956
# Number of predictions (with weights): 89956
# Task: CLASSIFICATION
# Label: __LABEL
#
# Accuracy: 0.959158  CI95[W][0.958056 0.960238]
# LogLoss: : 0.257968
# ErrorRate: : 0.0408422
#
# Default Accuracy: : 0.927453
# Default LogLoss: : 0.260177
# Default ErrorRate: : 0.0725466
#
# Confusion Table:
# truth\prediction
#        1     2
# 1  82924   506
# 2   3168  3358
# Total: 89956
#
#
# 2025-12-13 17:18:42.532251: I tensorflow_decision_forests/tensorflow/ops/inference/kernel.cc:1206] Loading model from path /tmp/tmpa9ox5t7z/model/ with prefix a378558beac94606
# I0000 00:00:1765646322.435171   26934 kernel.cc:944] Save model in resources
# I0000 00:00:1765646322.437499   18900 abstract_model.cc:921] Model self evaluation:
# Number of predictions (without weights): 89956
# Number of predictions (with weights): 89956
# Task: CLASSIFICATION
# Label: __LABEL
#
# Accuracy: 0.959158  CI95[W][0.958056 0.960238]
# LogLoss: : 0.257968
# ErrorRate: : 0.0408422
#
# Default Accuracy: : 0.927453
# Default LogLoss: : 0.260177
# Default ErrorRate: : 0.0725466
#
# Confusion Table:
# truth\prediction
#        1     2
# 1  82924   506
# 2   3168  3358
# Total: 89956
#
#
# 2025-12-13 17:18:42.532251: I tensorflow_decision_forests/tensorflow/ops/inference/kernel.cc:1206] Loading model from path /tmp/tmpa9ox5t7z/model/ with prefix a378558beac94606
# Model trained in 0:00:13.132025
# Compiling model...
# Compiling model...
# I0000 00:00:1765646323.321235   18900 decision_forest.cc:808] Model loaded with 300 root(s), 721922 node(s), and 18 input feature(s).
# I0000 00:00:1765646323.321353   18900 abstract_model.cc:1439] Engine "RandomForestOptPred" built
# 2025-12-13 17:18:43.321376: I tensorflow_decision_forests/tensorflow/ops/inference/kernel.cc:1035] Use fast generic engine
# Model compiled.
# CPU times: user 1min 52s, sys: 1.28 s, total: 1min 53s
# Wall time: 14 s
# CPU times: user 1min 52s, sys: 1.28 s, total: 1min 53s
# Wall time: 14 s

# %%
# Evaluate the model
evaluate = model.evaluate(val_ds, return_dict=True)
print()

for name, value in evaluate.items():
    print(f"{name}: {value:.4f}")
# Out:
# 23/23 [==============================] - 1s 30ms/step - loss: 0.0000e+00 - accuracy: 0.9591
#
# loss: 0.0000
# accuracy: 0.9591
# 23/23 [==============================] - 1s 30ms/step - loss: 0.0000e+00 - accuracy: 0.9591
#
# loss: 0.0000
# accuracy: 0.9591

# %%
# Model Summary
model.summary()
# Out:
# Model: "random_forest_model_14"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
# =================================================================
# Total params: 1 (1.00 Byte)
# Trainable params: 0 (0.00 Byte)
# Non-trainable params: 1 (1.00 Byte)
# _________________________________________________________________
# Type: "RANDOM_FOREST"
# Task: CLASSIFICATION
# Label: "__LABEL"
#
# Input Features (18):
# 	10Percentile
# 	90Percentile
# 	Energy
# 	Entropy
# 	InterquartileRange
# 	Kurtosis
# 	Maximum
# 	Mean
# 	MeanAbsoluteDeviation
# 	Median
# 	Minimum
# 	Range
# 	RobustMeanAbsoluteDeviation
# 	RootMeanSquared
# 	Skewness
# 	TotalEnergy
# 	Uniformity
# 	Variance
#
# No weights
#
# Variable Importance: INV_MEAN_MIN_DEPTH:
#     1.                 "TotalEnergy"  0.142545 ################
#     2.                     "Minimum"  0.136921 ##############
#     3.                      "Energy"  0.134707 #############
#     4.                     "Maximum"  0.130843 ############
#     5.             "RootMeanSquared"  0.130437 ############
#     6.                "90Percentile"  0.124036 ##########
#     7.                       "Range"  0.110081 #######
#     8.                        "Mean"  0.105786 #####
#     9.                    "Kurtosis"  0.099647 ####
#    10.                      "Median"  0.098906 ###
#    11.          "InterquartileRange"  0.097713 ###
#    12.                "10Percentile"  0.093463 ##
#    13.                  "Uniformity"  0.091406 #
#    14.                    "Skewness"  0.090943 #
#    15. "RobustMeanAbsoluteDeviation"  0.089623 #
#    16.                     "Entropy"  0.085872
#    17.       "MeanAbsoluteDeviation"  0.085137
#    18.                    "Variance"  0.084739
#
# Variable Importance: NUM_AS_ROOT:
#     1.     "TotalEnergy" 86.000000 ################
#     2.          "Energy" 77.000000 ##############
#     3. "RootMeanSquared" 65.000000 ############
#     4.            "Mean" 27.000000 ####
#     5.    "90Percentile" 19.000000 ###
#     6.          "Median" 11.000000 #
#     7.         "Maximum"  9.000000 #
#     8.    "10Percentile"  4.000000
#     9.         "Entropy"  1.000000
#    10.      "Uniformity"  1.000000
#
# Variable Importance: NUM_NODES:
#     1.                     "Maximum" 25989.000000 ################
#     2.                    "Skewness" 25690.000000 ###############
#     3.                       "Range" 25183.000000 ##############
#     4.                    "Kurtosis" 23676.000000 ############
#     5.                  "Uniformity" 22085.000000 ##########
#     6.                      "Median" 21107.000000 #########
#     7.                     "Entropy" 20977.000000 ########
#     8.                "90Percentile" 20364.000000 ########
#     9.          "InterquartileRange" 19885.000000 #######
#    10.                    "Variance" 19726.000000 #######
#    11. "RobustMeanAbsoluteDeviation" 19420.000000 ######
#    12.                     "Minimum" 19392.000000 ######
#    13.       "MeanAbsoluteDeviation" 18444.000000 #####
#    14.                "10Percentile" 18246.000000 #####
#    15.                        "Mean" 16586.000000 ##
#    16.                      "Energy" 14716.000000
#    17.             "RootMeanSquared" 14686.000000
#    18.                 "TotalEnergy" 14639.000000
#
# Variable Importance: SUM_SCORE:
#     1.                 "TotalEnergy" 707741.994660 ################
#     2.                      "Energy" 641553.398778 ##############
#     3.             "RootMeanSquared" 576240.714920 ############
#     4.                "90Percentile" 368100.978602 ######
#     5.                        "Mean" 348440.417885 ######
#     6.                     "Maximum" 341049.232201 #####
#     7.                      "Median" 284266.760743 ####
#     8.                     "Minimum" 267808.051746 ###
#     9.                       "Range" 252622.805763 ###
#    10.                    "Kurtosis" 233310.027361 ##
#    11.                    "Skewness" 197464.659581 #
#    12.          "InterquartileRange" 186109.673054 #
#    13.                "10Percentile" 176977.103132 #
#    14.                  "Uniformity" 165389.050954
#    15. "RobustMeanAbsoluteDeviation" 160389.496086
#    16.                     "Entropy" 142440.661346
#    17.                    "Variance" 133678.298967
#    18.       "MeanAbsoluteDeviation" 131840.251432
#
#
#
# Winner takes all: true
# Out-of-bag evaluation: accuracy:0.959158 logloss:0.257968
# Number of trees: 300
# Total number of nodes: 721922
#
# Number of nodes by tree:
# Count: 300 Average: 2406.41 StdDev: 143.153
# Min: 2049 Max: 2817 Ignored: 0
# ----------------------------------------------
# [ 2049, 2087)  3   1.00%   1.00% #
# [ 2087, 2125)  2   0.67%   1.67% #
# [ 2125, 2164)  3   1.00%   2.67% #
# [ 2164, 2202) 11   3.67%   6.33% ###
# [ 2202, 2241) 15   5.00%  11.33% ####
# [ 2241, 2279) 23   7.67%  19.00% ######
# [ 2279, 2318) 29   9.67%  28.67% ########
# [ 2318, 2356) 35  11.67%  40.33% #########
# [ 2356, 2395) 24   8.00%  48.33% ######
# [ 2395, 2433) 23   7.67%  56.00% ######
# [ 2433, 2471) 29   9.67%  65.67% ########
# [ 2471, 2510) 37  12.33%  78.00% ##########
# [ 2510, 2548) 18   6.00%  84.00% #####
# [ 2548, 2587) 13   4.33%  88.33% ####
# [ 2587, 2625) 12   4.00%  92.33% ###
# [ 2625, 2664)  9   3.00%  95.33% ##
# [ 2664, 2702)  6   2.00%  97.33% ##
# [ 2702, 2741)  4   1.33%  98.67% #
# [ 2741, 2779)  3   1.00%  99.67% #
# [ 2779, 2817]  1   0.33% 100.00%
#
# Depth by leafs:
# Count: 361111 Average: 12.6279 StdDev: 2.28993
# Min: 3 Max: 15 Ignored: 0
# ----------------------------------------------
# [  3,  4)     38   0.01%   0.01%
# [  4,  5)    381   0.11%   0.12%
# [  5,  6)   1077   0.30%   0.41%
# [  6,  7)   2645   0.73%   1.15%
# [  7,  8)   5995   1.66%   2.81% #
# [  8,  9)  11445   3.17%   5.98% #
# [  9, 10)  18822   5.21%  11.19% ##
# [ 10, 11)  26961   7.47%  18.65% ###
# [ 11, 12)  36493  10.11%  28.76% ###
# [ 12, 13)  45425  12.58%  41.34% ####
# [ 13, 14)  51918  14.38%  55.72% #####
# [ 14, 15)  55465  15.36%  71.08% #####
# [ 15, 15] 104446  28.92% 100.00% ##########
#
# Number of training obs by leaf:
# Count: 361111 Average: 74.7327 StdDev: 316.049
# Min: 5 Max: 11593 Ignored: 0
# ----------------------------------------------
# [     5,   584) 352349  97.57%  97.57% ##########
# [   584,  1163)   5134   1.42%  99.00%
# [  1163,  1743)   1483   0.41%  99.41%
# [  1743,  2322)    653   0.18%  99.59%
# [  2322,  2902)    412   0.11%  99.70%
# [  2902,  3481)    242   0.07%  99.77%
# [  3481,  4061)    194   0.05%  99.82%
# [  4061,  4640)    207   0.06%  99.88%
# [  4640,  5220)    182   0.05%  99.93%
# [  5220,  5799)    124   0.03%  99.96%
# [  5799,  6378)     59   0.02%  99.98%
# [  6378,  6958)     30   0.01%  99.99%
# [  6958,  7537)     17   0.00%  99.99%
# [  7537,  8117)     10   0.00% 100.00%
# [  8117,  8696)      3   0.00% 100.00%
# [  8696,  9276)      5   0.00% 100.00%
# [  9276,  9855)      1   0.00% 100.00%
# [  9855, 10435)      2   0.00% 100.00%
# [ 10435, 11014)      1   0.00% 100.00%
# [ 11014, 11593]      3   0.00% 100.00%
#
# Attribute in nodes:
# 	25989 : Maximum [NUMERICAL]
# 	25690 : Skewness [NUMERICAL]
# 	25183 : Range [NUMERICAL]
# 	23676 : Kurtosis [NUMERICAL]
# 	22085 : Uniformity [NUMERICAL]
# 	21107 : Median [NUMERICAL]
# 	20977 : Entropy [NUMERICAL]
# 	20364 : 90Percentile [NUMERICAL]
# 	19885 : InterquartileRange [NUMERICAL]
# 	19726 : Variance [NUMERICAL]
# 	19420 : RobustMeanAbsoluteDeviation [NUMERICAL]
# 	19392 : Minimum [NUMERICAL]
# 	18444 : MeanAbsoluteDeviation [NUMERICAL]
# 	18246 : 10Percentile [NUMERICAL]
# 	16586 : Mean [NUMERICAL]
# 	14716 : Energy [NUMERICAL]
# 	14686 : RootMeanSquared [NUMERICAL]
# 	14639 : TotalEnergy [NUMERICAL]
#
# Attribute in nodes with depth <= 0:
# 	86 : TotalEnergy [NUMERICAL]
# 	77 : Energy [NUMERICAL]
# 	65 : RootMeanSquared [NUMERICAL]
# 	27 : Mean [NUMERICAL]
# 	19 : 90Percentile [NUMERICAL]
# 	11 : Median [NUMERICAL]
# 	9 : Maximum [NUMERICAL]
# 	4 : 10Percentile [NUMERICAL]
# 	1 : Uniformity [NUMERICAL]
# 	1 : Entropy [NUMERICAL]
#
# Attribute in nodes with depth <= 1:
# 	175 : TotalEnergy [NUMERICAL]
# 	145 : RootMeanSquared [NUMERICAL]
# 	143 : Energy [NUMERICAL]
# 	97 : Minimum [NUMERICAL]
# 	90 : Median [NUMERICAL]
# 	86 : Mean [NUMERICAL]
# 	56 : Maximum [NUMERICAL]
# 	49 : 90Percentile [NUMERICAL]
# 	32 : 10Percentile [NUMERICAL]
# 	21 : Range [NUMERICAL]
# 	2 : RobustMeanAbsoluteDeviation [NUMERICAL]
# 	1 : Variance [NUMERICAL]
# 	1 : Uniformity [NUMERICAL]
# 	1 : MeanAbsoluteDeviation [NUMERICAL]
# 	1 : Entropy [NUMERICAL]
#
# Attribute in nodes with depth <= 2:
# 	271 : TotalEnergy [NUMERICAL]
# 	249 : RootMeanSquared [NUMERICAL]
# 	234 : Energy [NUMERICAL]
# 	218 : Median [NUMERICAL]
# 	204 : 90Percentile [NUMERICAL]
# 	198 : Mean [NUMERICAL]
# 	148 : Maximum [NUMERICAL]
# 	133 : Minimum [NUMERICAL]
# 	96 : 10Percentile [NUMERICAL]
# 	71 : Range [NUMERICAL]
# 	70 : Kurtosis [NUMERICAL]
# 	67 : InterquartileRange [NUMERICAL]
# 	60 : Uniformity [NUMERICAL]
# 	27 : Entropy [NUMERICAL]
# 	21 : Skewness [NUMERICAL]
# 	19 : RobustMeanAbsoluteDeviation [NUMERICAL]
# 	9 : MeanAbsoluteDeviation [NUMERICAL]
# 	5 : Variance [NUMERICAL]
#
# Attribute in nodes with depth <= 3:
# 	403 : TotalEnergy [NUMERICAL]
# 	387 : Energy [NUMERICAL]
# 	379 : 90Percentile [NUMERICAL]
# 	375 : RootMeanSquared [NUMERICAL]
# 	360 : Median [NUMERICAL]
# 	344 : Mean [NUMERICAL]
# 	329 : Maximum [NUMERICAL]
# 	289 : Minimum [NUMERICAL]
# 	248 : Range [NUMERICAL]
# 	230 : InterquartileRange [NUMERICAL]
# 	217 : Uniformity [NUMERICAL]
# 	203 : Kurtosis [NUMERICAL]
# 	171 : 10Percentile [NUMERICAL]
# 	167 : Skewness [NUMERICAL]
# 	133 : Entropy [NUMERICAL]
# 	107 : RobustMeanAbsoluteDeviation [NUMERICAL]
# 	65 : Variance [NUMERICAL]
# 	55 : MeanAbsoluteDeviation [NUMERICAL]
#
# Attribute in nodes with depth <= 5:
# 	1305 : Maximum [NUMERICAL]
# 	1185 : Range [NUMERICAL]
# 	1142 : 90Percentile [NUMERICAL]
# 	1089 : Kurtosis [NUMERICAL]
# 	1084 : Median [NUMERICAL]
# 	1024 : Uniformity [NUMERICAL]
# 	1018 : InterquartileRange [NUMERICAL]
# 	1016 : Skewness [NUMERICAL]
# 	951 : Minimum [NUMERICAL]
# 	867 : Mean [NUMERICAL]
# 	863 : TotalEnergy [NUMERICAL]
# 	848 : Energy [NUMERICAL]
# 	812 : RootMeanSquared [NUMERICAL]
# 	755 : Entropy [NUMERICAL]
# 	730 : 10Percentile [NUMERICAL]
# 	644 : RobustMeanAbsoluteDeviation [NUMERICAL]
# 	553 : Variance [NUMERICAL]
# 	528 : MeanAbsoluteDeviation [NUMERICAL]
#
# Condition type in nodes:
# 	360811 : HigherCondition
# Condition type in nodes with depth <= 0:
# 	300 : HigherCondition
# Condition type in nodes with depth <= 1:
# 	900 : HigherCondition
# Condition type in nodes with depth <= 2:
# 	2100 : HigherCondition
# Condition type in nodes with depth <= 3:
# 	4462 : HigherCondition
# Condition type in nodes with depth <= 5:
# 	16414 : HigherCondition
# Node format: NOT_SET
#
# Training OOB:
# 	trees: 1, Out-of-bag evaluation: accuracy:0.947539 logloss:1.89089
# 	trees: 11, Out-of-bag evaluation: accuracy:0.955599 logloss:0.976027
# 	trees: 21, Out-of-bag evaluation: accuracy:0.957022 logloss:0.725098
# 	trees: 31, Out-of-bag evaluation: accuracy:0.957312 logloss:0.621733
# 	trees: 41, Out-of-bag evaluation: accuracy:0.957724 logloss:0.550653
# 	trees: 51, Out-of-bag evaluation: accuracy:0.958124 logloss:0.505946
# 	trees: 61, Out-of-bag evaluation: accuracy:0.958502 logloss:0.47039
# 	trees: 71, Out-of-bag evaluation: accuracy:0.958569 logloss:0.441315
# 	trees: 81, Out-of-bag evaluation: accuracy:0.958746 logloss:0.418227
# 	trees: 91, Out-of-bag evaluation: accuracy:0.958913 logloss:0.40135
# 	trees: 101, Out-of-bag evaluation: accuracy:0.958835 logloss:0.383772
# 	trees: 111, Out-of-bag evaluation: accuracy:0.958791 logloss:0.366531
# 	trees: 121, Out-of-bag evaluation: accuracy:0.959013 logloss:0.358459
# 	trees: 131, Out-of-bag evaluation: accuracy:0.959047 logloss:0.34846
# 	trees: 141, Out-of-bag evaluation: accuracy:0.959191 logloss:0.337069
# 	trees: 151, Out-of-bag evaluation: accuracy:0.95898 logloss:0.329822
# 	trees: 161, Out-of-bag evaluation: accuracy:0.959124 logloss:0.320925
# 	trees: 171, Out-of-bag evaluation: accuracy:0.959169 logloss:0.312721
# 	trees: 181, Out-of-bag evaluation: accuracy:0.959102 logloss:0.307475
# 	trees: 191, Out-of-bag evaluation: accuracy:0.95918 logloss:0.303724
# 	trees: 201, Out-of-bag evaluation: accuracy:0.959024 logloss:0.299145
# 	trees: 211, Out-of-bag evaluation: accuracy:0.959024 logloss:0.294978
# 	trees: 221, Out-of-bag evaluation: accuracy:0.958958 logloss:0.288626
# 	trees: 231, Out-of-bag evaluation: accuracy:0.959036 logloss:0.28511
# 	trees: 241, Out-of-bag evaluation: accuracy:0.959102 logloss:0.278889
# 	trees: 251, Out-of-bag evaluation: accuracy:0.959213 logloss:0.276107
# 	trees: 261, Out-of-bag evaluation: accuracy:0.959136 logloss:0.273
# 	trees: 271, Out-of-bag evaluation: accuracy:0.959024 logloss:0.269893
# 	trees: 281, Out-of-bag evaluation: accuracy:0.95918 logloss:0.266027
# 	trees: 291, Out-of-bag evaluation: accuracy:0.959058 logloss:0.261136
# 	trees: 300, Out-of-bag evaluation: accuracy:0.959158 logloss:0.257968
#
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
# =================================================================
# Total params: 1 (1.00 Byte)
# Trainable params: 0 (0.00 Byte)
# Non-trainable params: 1 (1.00 Byte)
# _________________________________________________________________
# Type: "RANDOM_FOREST"
# Task: CLASSIFICATION
# Label: "__LABEL"
#
# Input Features (18):
# 	10Percentile
# 	90Percentile
# 	Energy
# 	Entropy
# 	InterquartileRange
# 	Kurtosis
# 	Maximum
# 	Mean
# 	MeanAbsoluteDeviation
# 	Median
# 	Minimum
# 	Range
# 	RobustMeanAbsoluteDeviation
# 	RootMeanSquared
# 	Skewness
# 	TotalEnergy
# 	Uniformity
# 	Variance
#
# No weights
#
# Variable Importance: INV_MEAN_MIN_DEPTH:
#     1.                 "TotalEnergy"  0.142545 ################
#     2.                     "Minimum"  0.136921 ##############
#     3.                      "Energy"  0.134707 #############
#     4.                     "Maximum"  0.130843 ############
#     5.             "RootMeanSquared"  0.130437 ############
#     6.                "90Percentile"  0.124036 ##########
#     7.                       "Range"  0.110081 #######
#     8.                        "Mean"  0.105786 #####
#     9.                    "Kurtosis"  0.099647 ####
#    10.                      "Median"  0.098906 ###
#    11.          "InterquartileRange"  0.097713 ###
#    12.                "10Percentile"  0.093463 ##
#    13.                  "Uniformity"  0.091406 #
#    14.                    "Skewness"  0.090943 #
#    15. "RobustMeanAbsoluteDeviation"  0.089623 #
#    16.                     "Entropy"  0.085872
#    17.       "MeanAbsoluteDeviation"  0.085137
#    18.                    "Variance"  0.084739
#
# Variable Importance: NUM_AS_ROOT:
#     1.     "TotalEnergy" 86.000000 ################
#     2.          "Energy" 77.000000 ##############
#     3. "RootMeanSquared" 65.000000 ############
#     4.            "Mean" 27.000000 ####
#     5.    "90Percentile" 19.000000 ###
#     6.          "Median" 11.000000 #
#     7.         "Maximum"  9.000000 #
#     8.    "10Percentile"  4.000000
#     9.         "Entropy"  1.000000
#    10.      "Uniformity"  1.000000
#
# Variable Importance: NUM_NODES:
#     1.                     "Maximum" 25989.000000 ################
#     2.                    "Skewness" 25690.000000 ###############
#     3.                       "Range" 25183.000000 ##############
#     4.                    "Kurtosis" 23676.000000 ############
#     5.                  "Uniformity" 22085.000000 ##########
#     6.                      "Median" 21107.000000 #########
#     7.                     "Entropy" 20977.000000 ########
#     8.                "90Percentile" 20364.000000 ########
#     9.          "InterquartileRange" 19885.000000 #######
#    10.                    "Variance" 19726.000000 #######
#    11. "RobustMeanAbsoluteDeviation" 19420.000000 ######
#    12.                     "Minimum" 19392.000000 ######
#    13.       "MeanAbsoluteDeviation" 18444.000000 #####
#    14.                "10Percentile" 18246.000000 #####
#    15.                        "Mean" 16586.000000 ##
#    16.                      "Energy" 14716.000000
#    17.             "RootMeanSquared" 14686.000000
#    18.                 "TotalEnergy" 14639.000000
#
# Variable Importance: SUM_SCORE:
#     1.                 "TotalEnergy" 707741.994660 ################
#     2.                      "Energy" 641553.398778 ##############
#     3.             "RootMeanSquared" 576240.714920 ############
#     4.                "90Percentile" 368100.978602 ######
#     5.                        "Mean" 348440.417885 ######
#     6.                     "Maximum" 341049.232201 #####
#     7.                      "Median" 284266.760743 ####
#     8.                     "Minimum" 267808.051746 ###
#     9.                       "Range" 252622.805763 ###
#    10.                    "Kurtosis" 233310.027361 ##
#    11.                    "Skewness" 197464.659581 #
#    12.          "InterquartileRange" 186109.673054 #
#    13.                "10Percentile" 176977.103132 #
#    14.                  "Uniformity" 165389.050954
#    15. "RobustMeanAbsoluteDeviation" 160389.496086
#    16.                     "Entropy" 142440.661346
#    17.                    "Variance" 133678.298967
#    18.       "MeanAbsoluteDeviation" 131840.251432
#
#
#
# Winner takes all: true
# Out-of-bag evaluation: accuracy:0.959158 logloss:0.257968
# Number of trees: 300
# Total number of nodes: 721922
#
# Number of nodes by tree:
# Count: 300 Average: 2406.41 StdDev: 143.153
# Min: 2049 Max: 2817 Ignored: 0
# ----------------------------------------------
# [ 2049, 2087)  3   1.00%   1.00% #
# [ 2087, 2125)  2   0.67%   1.67% #
# [ 2125, 2164)  3   1.00%   2.67% #
# [ 2164, 2202) 11   3.67%   6.33% ###
# [ 2202, 2241) 15   5.00%  11.33% ####
# [ 2241, 2279) 23   7.67%  19.00% ######
# [ 2279, 2318) 29   9.67%  28.67% ########
# [ 2318, 2356) 35  11.67%  40.33% #########
# [ 2356, 2395) 24   8.00%  48.33% ######
# [ 2395, 2433) 23   7.67%  56.00% ######
# [ 2433, 2471) 29   9.67%  65.67% ########
# [ 2471, 2510) 37  12.33%  78.00% ##########
# [ 2510, 2548) 18   6.00%  84.00% #####
# [ 2548, 2587) 13   4.33%  88.33% ####
# [ 2587, 2625) 12   4.00%  92.33% ###
# [ 2625, 2664)  9   3.00%  95.33% ##
# [ 2664, 2702)  6   2.00%  97.33% ##
# [ 2702, 2741)  4   1.33%  98.67% #
# [ 2741, 2779)  3   1.00%  99.67% #
# [ 2779, 2817]  1   0.33% 100.00%
#
# Depth by leafs:
# Count: 361111 Average: 12.6279 StdDev: 2.28993
# Min: 3 Max: 15 Ignored: 0
# ----------------------------------------------
# [  3,  4)     38   0.01%   0.01%
# [  4,  5)    381   0.11%   0.12%
# [  5,  6)   1077   0.30%   0.41%
# [  6,  7)   2645   0.73%   1.15%
# [  7,  8)   5995   1.66%   2.81% #
# [  8,  9)  11445   3.17%   5.98% #
# [  9, 10)  18822   5.21%  11.19% ##
# [ 10, 11)  26961   7.47%  18.65% ###
# [ 11, 12)  36493  10.11%  28.76% ###
# [ 12, 13)  45425  12.58%  41.34% ####
# [ 13, 14)  51918  14.38%  55.72% #####
# [ 14, 15)  55465  15.36%  71.08% #####
# [ 15, 15] 104446  28.92% 100.00% ##########
#
# Number of training obs by leaf:
# Count: 361111 Average: 74.7327 StdDev: 316.049
# Min: 5 Max: 11593 Ignored: 0
# ----------------------------------------------
# [     5,   584) 352349  97.57%  97.57% ##########
# [   584,  1163)   5134   1.42%  99.00%
# [  1163,  1743)   1483   0.41%  99.41%
# [  1743,  2322)    653   0.18%  99.59%
# [  2322,  2902)    412   0.11%  99.70%
# [  2902,  3481)    242   0.07%  99.77%
# [  3481,  4061)    194   0.05%  99.82%
# [  4061,  4640)    207   0.06%  99.88%
# [  4640,  5220)    182   0.05%  99.93%
# [  5220,  5799)    124   0.03%  99.96%
# [  5799,  6378)     59   0.02%  99.98%
# [  6378,  6958)     30   0.01%  99.99%
# [  6958,  7537)     17   0.00%  99.99%
# [  7537,  8117)     10   0.00% 100.00%
# [  8117,  8696)      3   0.00% 100.00%
# [  8696,  9276)      5   0.00% 100.00%
# [  9276,  9855)      1   0.00% 100.00%
# [  9855, 10435)      2   0.00% 100.00%
# [ 10435, 11014)      1   0.00% 100.00%
# [ 11014, 11593]      3   0.00% 100.00%
#
# Attribute in nodes:
# 	25989 : Maximum [NUMERICAL]
# 	25690 : Skewness [NUMERICAL]
# 	25183 : Range [NUMERICAL]
# 	23676 : Kurtosis [NUMERICAL]
# 	22085 : Uniformity [NUMERICAL]
# 	21107 : Median [NUMERICAL]
# 	20977 : Entropy [NUMERICAL]
# 	20364 : 90Percentile [NUMERICAL]
# 	19885 : InterquartileRange [NUMERICAL]
# 	19726 : Variance [NUMERICAL]
# 	19420 : RobustMeanAbsoluteDeviation [NUMERICAL]
# 	19392 : Minimum [NUMERICAL]
# 	18444 : MeanAbsoluteDeviation [NUMERICAL]
# 	18246 : 10Percentile [NUMERICAL]
# 	16586 : Mean [NUMERICAL]
# 	14716 : Energy [NUMERICAL]
# 	14686 : RootMeanSquared [NUMERICAL]
# 	14639 : TotalEnergy [NUMERICAL]
#
# Attribute in nodes with depth <= 0:
# 	86 : TotalEnergy [NUMERICAL]
# 	77 : Energy [NUMERICAL]
# 	65 : RootMeanSquared [NUMERICAL]
# 	27 : Mean [NUMERICAL]
# 	19 : 90Percentile [NUMERICAL]
# 	11 : Median [NUMERICAL]
# 	9 : Maximum [NUMERICAL]
# 	4 : 10Percentile [NUMERICAL]
# 	1 : Uniformity [NUMERICAL]
# 	1 : Entropy [NUMERICAL]
#
# Attribute in nodes with depth <= 1:
# 	175 : TotalEnergy [NUMERICAL]
# 	145 : RootMeanSquared [NUMERICAL]
# 	143 : Energy [NUMERICAL]
# 	97 : Minimum [NUMERICAL]
# 	90 : Median [NUMERICAL]
# 	86 : Mean [NUMERICAL]
# 	56 : Maximum [NUMERICAL]
# 	49 : 90Percentile [NUMERICAL]
# 	32 : 10Percentile [NUMERICAL]
# 	21 : Range [NUMERICAL]
# 	2 : RobustMeanAbsoluteDeviation [NUMERICAL]
# 	1 : Variance [NUMERICAL]
# 	1 : Uniformity [NUMERICAL]
# 	1 : MeanAbsoluteDeviation [NUMERICAL]
# 	1 : Entropy [NUMERICAL]
#
# Attribute in nodes with depth <= 2:
# 	271 : TotalEnergy [NUMERICAL]
# 	249 : RootMeanSquared [NUMERICAL]
# 	234 : Energy [NUMERICAL]
# 	218 : Median [NUMERICAL]
# 	204 : 90Percentile [NUMERICAL]
# 	198 : Mean [NUMERICAL]
# 	148 : Maximum [NUMERICAL]
# 	133 : Minimum [NUMERICAL]
# 	96 : 10Percentile [NUMERICAL]
# 	71 : Range [NUMERICAL]
# 	70 : Kurtosis [NUMERICAL]
# 	67 : InterquartileRange [NUMERICAL]
# 	60 : Uniformity [NUMERICAL]
# 	27 : Entropy [NUMERICAL]
# 	21 : Skewness [NUMERICAL]
# 	19 : RobustMeanAbsoluteDeviation [NUMERICAL]
# 	9 : MeanAbsoluteDeviation [NUMERICAL]
# 	5 : Variance [NUMERICAL]
#
# Attribute in nodes with depth <= 3:
# 	403 : TotalEnergy [NUMERICAL]
# 	387 : Energy [NUMERICAL]
# 	379 : 90Percentile [NUMERICAL]
# 	375 : RootMeanSquared [NUMERICAL]
# 	360 : Median [NUMERICAL]
# 	344 : Mean [NUMERICAL]
# 	329 : Maximum [NUMERICAL]
# 	289 : Minimum [NUMERICAL]
# 	248 : Range [NUMERICAL]
# 	230 : InterquartileRange [NUMERICAL]
# 	217 : Uniformity [NUMERICAL]
# 	203 : Kurtosis [NUMERICAL]
# 	171 : 10Percentile [NUMERICAL]
# 	167 : Skewness [NUMERICAL]
# 	133 : Entropy [NUMERICAL]
# 	107 : RobustMeanAbsoluteDeviation [NUMERICAL]
# 	65 : Variance [NUMERICAL]
# 	55 : MeanAbsoluteDeviation [NUMERICAL]
#
# Attribute in nodes with depth <= 5:
# 	1305 : Maximum [NUMERICAL]
# 	1185 : Range [NUMERICAL]
# 	1142 : 90Percentile [NUMERICAL]
# 	1089 : Kurtosis [NUMERICAL]
# 	1084 : Median [NUMERICAL]
# 	1024 : Uniformity [NUMERICAL]
# 	1018 : InterquartileRange [NUMERICAL]
# 	1016 : Skewness [NUMERICAL]
# 	951 : Minimum [NUMERICAL]
# 	867 : Mean [NUMERICAL]
# 	863 : TotalEnergy [NUMERICAL]
# 	848 : Energy [NUMERICAL]
# 	812 : RootMeanSquared [NUMERICAL]
# 	755 : Entropy [NUMERICAL]
# 	730 : 10Percentile [NUMERICAL]
# 	644 : RobustMeanAbsoluteDeviation [NUMERICAL]
# 	553 : Variance [NUMERICAL]
# 	528 : MeanAbsoluteDeviation [NUMERICAL]
#
# Condition type in nodes:
# 	360811 : HigherCondition
# Condition type in nodes with depth <= 0:
# 	300 : HigherCondition
# Condition type in nodes with depth <= 1:
# 	900 : HigherCondition
# Condition type in nodes with depth <= 2:
# 	2100 : HigherCondition
# Condition type in nodes with depth <= 3:
# 	4462 : HigherCondition
# Condition type in nodes with depth <= 5:
# 	16414 : HigherCondition
# Node format: NOT_SET
#
# Training OOB:
# 	trees: 1, Out-of-bag evaluation: accuracy:0.947539 logloss:1.89089
# 	trees: 11, Out-of-bag evaluation: accuracy:0.955599 logloss:0.976027
# 	trees: 21, Out-of-bag evaluation: accuracy:0.957022 logloss:0.725098
# 	trees: 31, Out-of-bag evaluation: accuracy:0.957312 logloss:0.621733
# 	trees: 41, Out-of-bag evaluation: accuracy:0.957724 logloss:0.550653
# 	trees: 51, Out-of-bag evaluation: accuracy:0.958124 logloss:0.505946
# 	trees: 61, Out-of-bag evaluation: accuracy:0.958502 logloss:0.47039
# 	trees: 71, Out-of-bag evaluation: accuracy:0.958569 logloss:0.441315
# 	trees: 81, Out-of-bag evaluation: accuracy:0.958746 logloss:0.418227
# 	trees: 91, Out-of-bag evaluation: accuracy:0.958913 logloss:0.40135
# 	trees: 101, Out-of-bag evaluation: accuracy:0.958835 logloss:0.383772
# 	trees: 111, Out-of-bag evaluation: accuracy:0.958791 logloss:0.366531
# 	trees: 121, Out-of-bag evaluation: accuracy:0.959013 logloss:0.358459
# 	trees: 131, Out-of-bag evaluation: accuracy:0.959047 logloss:0.34846
# 	trees: 141, Out-of-bag evaluation: accuracy:0.959191 logloss:0.337069
# 	trees: 151, Out-of-bag evaluation: accuracy:0.95898 logloss:0.329822
# 	trees: 161, Out-of-bag evaluation: accuracy:0.959124 logloss:0.320925
# 	trees: 171, Out-of-bag evaluation: accuracy:0.959169 logloss:0.312721
# 	trees: 181, Out-of-bag evaluation: accuracy:0.959102 logloss:0.307475
# 	trees: 191, Out-of-bag evaluation: accuracy:0.95918 logloss:0.303724
# 	trees: 201, Out-of-bag evaluation: accuracy:0.959024 logloss:0.299145
# 	trees: 211, Out-of-bag evaluation: accuracy:0.959024 logloss:0.294978
# 	trees: 221, Out-of-bag evaluation: accuracy:0.958958 logloss:0.288626
# 	trees: 231, Out-of-bag evaluation: accuracy:0.959036 logloss:0.28511
# 	trees: 241, Out-of-bag evaluation: accuracy:0.959102 logloss:0.278889
# 	trees: 251, Out-of-bag evaluation: accuracy:0.959213 logloss:0.276107
# 	trees: 261, Out-of-bag evaluation: accuracy:0.959136 logloss:0.273
# 	trees: 271, Out-of-bag evaluation: accuracy:0.959024 logloss:0.269893
# 	trees: 281, Out-of-bag evaluation: accuracy:0.95918 logloss:0.266027
# 	trees: 291, Out-of-bag evaluation: accuracy:0.959058 logloss:0.261136
# 	trees: 300, Out-of-bag evaluation: accuracy:0.959158 logloss:0.257968

# %%
# Model features
model.make_inspector().features()
# Out:
# ["10Percentile" (1; #0),
#  "90Percentile" (1; #1),
#  "Energy" (1; #2),
#  "Entropy" (1; #3),
#  "InterquartileRange" (1; #4),
#  "Kurtosis" (1; #5),
#  "Maximum" (1; #6),
#  "Mean" (1; #7),
#  "MeanAbsoluteDeviation" (1; #8),
#  "Median" (1; #9),
#  "Minimum" (1; #10),
#  "Range" (1; #11),
#  "RobustMeanAbsoluteDeviation" (1; #12),
#  "RootMeanSquared" (1; #13),
#  "Skewness" (1; #14),
#  "TotalEnergy" (1; #15),
#  "Uniformity" (1; #16),
#  "Variance" (1; #17)]

# %%
# Feature importance
model.make_inspector().variable_importances()
# Out:
# {'INV_MEAN_MIN_DEPTH': [("TotalEnergy" (1; #15), 0.14254509666301862),
#   ("Minimum" (1; #10), 0.13692076181491064),
#   ("Energy" (1; #2), 0.13470741683449264),
#   ("Maximum" (1; #6), 0.13084273332855406),
#   ("RootMeanSquared" (1; #13), 0.1304374264457781),
#   ("90Percentile" (1; #1), 0.12403601965078255),
#   ("Range" (1; #11), 0.11008142340643252),
#   ("Mean" (1; #7), 0.1057856044809835),
#   ("Kurtosis" (1; #5), 0.09964731940857313),
#   ("Median" (1; #9), 0.09890607368134965),
#   ("InterquartileRange" (1; #4), 0.09771307642367552),
#   ("10Percentile" (1; #0), 0.0934626160588648),
#   ("Uniformity" (1; #16), 0.09140611832402588),
#   ("Skewness" (1; #14), 0.09094340682450568),
#   ("RobustMeanAbsoluteDeviation" (1; #12), 0.08962268658033112),
#   ("Entropy" (1; #3), 0.08587212148902273),
#   ("MeanAbsoluteDeviation" (1; #8), 0.08513675372202571),
#   ("Variance" (1; #17), 0.08473894656771146)],
#  'NUM_AS_ROOT': [("TotalEnergy" (1; #15), 86.0),
#   ("Energy" (1; #2), 77.0),
#   ("RootMeanSquared" (1; #13), 65.0),
#   ("Mean" (1; #7), 27.0),
#   ("90Percentile" (1; #1), 19.0),
#   ("Median" (1; #9), 11.0),
#   ("Maximum" (1; #6), 9.0),
#   ("10Percentile" (1; #0), 4.0),
#   ("Entropy" (1; #3), 1.0),
#   ("Uniformity" (1; #16), 1.0)],
#  'SUM_SCORE': [("TotalEnergy" (1; #15), 707741.9946599584),
#   ("Energy" (1; #2), 641553.3987782998),
#   ("RootMeanSquared" (1; #13), 576240.714919679),
#   ("90Percentile" (1; #1), 368100.9786017201),
#   ("Mean" (1; #7), 348440.4178852985),
#   ("Maximum" (1; #6), 341049.2322009785),
#   ("Median" (1; #9), 284266.7607426037),
#   ("Minimum" (1; #10), 267808.05174615677),
#   ("Range" (1; #11), 252622.8057634744),
#   ("Kurtosis" (1; #5), 233310.02736129338),
#   ("Skewness" (1; #14), 197464.65958148762),
#   ("InterquartileRange" (1; #4), 186109.67305408808),
#   ("10Percentile" (1; #0), 176977.10313180392),
#   ("Uniformity" (1; #16), 165389.05095356767),
#   ("RobustMeanAbsoluteDeviation" (1; #12), 160389.49608622753),
#   ("Entropy" (1; #3), 142440.6613461585),
#   ("Variance" (1; #17), 133678.29896734186),
#   ("MeanAbsoluteDeviation" (1; #8), 131840.25143161064)],
#  'NUM_NODES': [("Maximum" (1; #6), 25989.0),
#   ("Skewness" (1; #14), 25690.0),
#   ("Range" (1; #11), 25183.0),
#   ("Kurtosis" (1; #5), 23676.0),
#   ("Uniformity" (1; #16), 22085.0),
#   ("Median" (1; #9), 21107.0),
#   ("Entropy" (1; #3), 20977.0),
#   ("90Percentile" (1; #1), 20364.0),
#   ("InterquartileRange" (1; #4), 19885.0),
#   ("Variance" (1; #17), 19726.0),
#   ("RobustMeanAbsoluteDeviation" (1; #12), 19420.0),
#   ("Minimum" (1; #10), 19392.0),
#   ("MeanAbsoluteDeviation" (1; #8), 18444.0),
#   ("10Percentile" (1; #0), 18246.0),
#   ("Mean" (1; #7), 16586.0),
#   ("Energy" (1; #2), 14716.0),
#   ("RootMeanSquared" (1; #13), 14686.0),
#   ("TotalEnergy" (1; #15), 14639.0)]}

# %%
# Model self evaluation
model.make_inspector().evaluation()
# Out:
# Evaluation(num_examples=89956, accuracy=0.959157810485126, loss=0.2579680470950596, rmse=None, ndcg=None, aucs=None, auuc=None, qini=None)

# %%
logs = model.make_inspector().training_logs()

plt.figure(figsize=(12, 4))
plt.subplot(1, 2, 1)
plt.plot([log.num_trees for log in logs], [log.evaluation.accuracy for log in logs])
plt.xlabel("Number of trees")
plt.ylabel("Accuracy (out-of-bag)")
plt.subplot(1, 2, 2)
plt.plot([log.num_trees for log in logs], [log.evaluation.loss for log in logs])
plt.xlabel("Number of trees")
plt.ylabel("Logloss (out-of-bag)")
plt.show()

# %% [markdown]
# Calculate the score of our hold-out validation dataset

# %%
predictions = model.predict(val_ds)
y_true      = validation_data["label"]

from sklearn.metrics import roc_auc_score
ROC_AUC = roc_auc_score(y_true, predictions)
print("The ROC AUC score is %.5f" % ROC_AUC )
# Out:
# 23/23 [==============================] - 1s 31ms/step
# 23/23 [==============================] - 1s 31ms/step
# The ROC AUC score is 0.93408
# The ROC AUC score is 0.93408

# %%
# Compute binary classification metrics with sklearn
import numpy as np
from sklearn.metrics import (
    accuracy_score,
    precision_score,
    recall_score,
    f1_score,
    roc_auc_score,
    average_precision_score,
    confusion_matrix,
    classification_report,
    matthews_corrcoef,
    log_loss,
    brier_score_loss,
)

# Get predictions (probabilities or class labels)
preds = model.predict(val_ds)
# If model outputs probabilities, convert to labels by threshold 0.5
if preds.ndim == 2:
    # For TFDF classification, preds may be class probabilities with shape (N, 2)
    if preds.shape[1] == 2:
        pos_probs = preds[:, 1]
    else:
        # If single-probability column (positive class)
        pos_probs = preds[:, -1]
    y_pred = (pos_probs >= 0.5).astype(int)
else:
    # Already class labels
    y_pred = preds.astype(int)
    pos_probs = None

# Ground truth labels (must be 0/1 integers)
y_true = validation_data["label"].astype(int).to_numpy()

# Core metrics
metrics = {}
metrics["accuracy"] = accuracy_score(y_true, y_pred)
metrics["precision"] = precision_score(y_true, y_pred, zero_division=0)
metrics["recall"] = recall_score(y_true, y_pred, zero_division=0)
metrics["f1"] = f1_score(y_true, y_pred, zero_division=0)
metrics["mcc"] = matthews_corrcoef(y_true, y_pred)

# Probabilistic metrics (only if we have probabilities)
if pos_probs is not None:
    metrics["roc_auc"] = roc_auc_score(y_true, pos_probs)
    metrics["pr_auc"] = average_precision_score(y_true, pos_probs)
    metrics["log_loss"] = log_loss(y_true, pos_probs, labels=[0,1])
    metrics["brier_score"] = brier_score_loss(y_true, pos_probs)

# Confusion matrix and detailed report
cm = confusion_matrix(y_true, y_pred, labels=[0,1])
report = classification_report(y_true, y_pred, digits=4)

print("Sklearn binary metrics:")
for k, v in metrics.items():
    print(f"{k}: {v:.4f}")
print("\nConfusion matrix:\n", cm)
print("\nClassification report:\n", report)
# Out:
# 23/23 [==============================] - 1s 31ms/step
# Sklearn binary metrics:
# accuracy: 0.9591
# precision: 0.8619
# recall: 0.5115
# f1: 0.6420
# mcc: 0.6457
# roc_auc: 0.9341
# pr_auc: 0.7324
# log_loss: 0.1497
# brier_score: 0.0331
#
# Confusion matrix:
#  [[20747   132]
#  [  787   824]]
#
# Classification report:
#                precision    recall  f1-score   support
#
#            0     0.9635    0.9937    0.9783     20879
#            1     0.8619    0.5115    0.6420      1611
#
#     accuracy                         0.9591     22490
#    macro avg     0.9127    0.7526    0.8102     22490
# weighted avg     0.9562    0.9591    0.9542     22490
