# %%
# Import packages and modules
import numpy  as np
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow_decision_forests as tfdf

from sklearn.model_selection import train_test_split
# Out:
# 2026-05-18 17:50:41.398625: I tensorflow/core/util/port.cc:113] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2026-05-18 17:50:41.565986: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2026-05-18 17:50:43.124073: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
# Check the version of TensorFlow Decision Forests
print("Found TensorFlow Decision Forests v" + tfdf.__version__)
# Out:
# Found TensorFlow Decision Forests v1.9.1

# %%
# train/validation/test = 70/10/20
dataset = pd.read_csv('dataset/glszm/kernel5-radius5/dataset.csv')

train_data, temp_data = train_test_split(
    dataset, test_size=0.3, random_state=42
 )
validation_data, test_data = train_test_split(
    temp_data, test_size=2/3, random_state=42
 )

# %%
# Convert the dataset into a TensorFlow dataset.
train_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    train_data, label="label"
)         
val_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    validation_data, label="label"
)
test_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    test_data, label="label"
)
# Out:
# 2026-05-18 17:50:46.009555: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:984] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2026-05-18 17:50:46.010086: W tensorflow/core/common_runtime/gpu/gpu_device.cc:2251] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...

# %%
import keras

# %%
# %%time

# Train a Gradient Boosted Trees model.
model = tfdf.keras.GradientBoostedTreesModel()

# Add evaluation metrics
model.compile(
    metrics=["accuracy"]
)
model.fit(x=train_ds)

# # Train a Gradient Boosted Trees model.
# model = tfdf.keras.GradientBoostedTreesModel(num_trees=1500)
# model.fit(train_ds)
# Out:
# Use /tmp/tmpmhvgqfwo as temporary training directory
# Reading training dataset...
# [WARNING 26-05-18 17:50:46.3017 UTC gradient_boosted_trees.cc:1840] "goss_alpha" set but "sampling_method" not equal to "GOSS".
# [WARNING 26-05-18 17:50:46.3018 UTC gradient_boosted_trees.cc:1851] "goss_beta" set but "sampling_method" not equal to "GOSS".
# [WARNING 26-05-18 17:50:46.3018 UTC gradient_boosted_trees.cc:1865] "selective_gradient_boosting_ratio" set but "sampling_method" not equal to "SELGB".
# Training dataset read in 0:00:05.472159. Found 78712 examples.
# Training model...
# Model trained in 0:00:51.845363
# Compiling model...
# [INFO 26-05-18 17:51:43.6667 UTC kernel.cc:1233] Loading model from path /tmp/tmpmhvgqfwo/model/ with prefix 2ab5256855664905
# [INFO 26-05-18 17:51:43.6869 UTC quick_scorer_extended.cc:911] The binary was compiled without AVX2 support, but your CPU supports it. Enable it for faster model inference.
# [INFO 26-05-18 17:51:43.6883 UTC abstract_model.cc:1362] Engine "GradientBoostedTreesQuickScorerExtended" built
# [INFO 26-05-18 17:51:43.6883 UTC kernel.cc:1061] Use fast generic engine
# Model compiled.
# CPU times: user 2min 15s, sys: 3.16 s, total: 2min 18s
# Wall time: 1min 2s

# %%
# Evaluate the model
evaluate = model.evaluate(val_ds, return_dict=True)
print()

for name, value in evaluate.items():
    print(f"{name}: {value:.4f}")
# Out:
# 12/12 [==============================] - 4s 7ms/step - loss: 0.0000e+00 - accuracy: 0.9627
#
# loss: 0.0000
# accuracy: 0.9627

# %%
# Model Summary
model.summary()
# Out:
# Model: "gradient_boosted_trees_model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
# =================================================================
# Total params: 1 (1.00 Byte)
# Trainable params: 0 (0.00 Byte)
# Non-trainable params: 1 (1.00 Byte)
# _________________________________________________________________
# Type: "GRADIENT_BOOSTED_TREES"
# Task: CLASSIFICATION
# Label: "__LABEL"
#
# Input Features (16):
# 	GrayLevelNonUniformity
# 	GrayLevelNonUniformityNormalized
# 	GrayLevelVariance
# 	HighGrayLevelZoneEmphasis
# 	LargeAreaEmphasis
# 	LargeAreaHighGrayLevelEmphasis
# 	LargeAreaLowGrayLevelEmphasis
# 	LowGrayLevelZoneEmphasis
# 	SizeZoneNonUniformity
# 	SizeZoneNonUniformityNormalized
# 	SmallAreaEmphasis
# 	SmallAreaHighGrayLevelEmphasis
# 	SmallAreaLowGrayLevelEmphasis
# 	ZoneEntropy
# 	ZonePercentage
# 	ZoneVariance
#
# No weights
#
# Variable Importance: INV_MEAN_MIN_DEPTH:
#     1.    "LargeAreaLowGrayLevelEmphasis"  0.240744 ################
#     2.   "LargeAreaHighGrayLevelEmphasis"  0.230319 #############
#     3.        "HighGrayLevelZoneEmphasis"  0.218566 ##########
#     4.                     "ZoneVariance"  0.216494 #########
#     5.           "GrayLevelNonUniformity"  0.208086 #######
#     6.                      "ZoneEntropy"  0.198395 #####
#     7. "GrayLevelNonUniformityNormalized"  0.197050 ####
#     8.  "SizeZoneNonUniformityNormalized"  0.194416 ####
#     9.         "LowGrayLevelZoneEmphasis"  0.192477 ###
#    10.    "SmallAreaLowGrayLevelEmphasis"  0.190456 ###
#    11.                "GrayLevelVariance"  0.189354 ##
#    12.   "SmallAreaHighGrayLevelEmphasis"  0.188436 ##
#    13.                "SmallAreaEmphasis"  0.183808 #
#    14.                   "ZonePercentage"  0.180028
#    15.            "SizeZoneNonUniformity"  0.179600
#    16.                "LargeAreaEmphasis"  0.178231
#
# Variable Importance: NUM_AS_ROOT:
#     1.    "LargeAreaLowGrayLevelEmphasis" 58.000000 ################
#     2.        "HighGrayLevelZoneEmphasis" 40.000000 ##########
#     3.                     "ZoneVariance" 38.000000 ##########
#     4.   "LargeAreaHighGrayLevelEmphasis" 33.000000 ########
#     5.  "SizeZoneNonUniformityNormalized" 27.000000 #######
#     6.           "GrayLevelNonUniformity" 17.000000 ####
#     7. "GrayLevelNonUniformityNormalized" 15.000000 ###
#     8.                "SmallAreaEmphasis" 11.000000 ##
#     9.    "SmallAreaLowGrayLevelEmphasis"  8.000000 #
#    10.                "GrayLevelVariance"  2.000000
#    11.                "LargeAreaEmphasis"  2.000000
#    12.         "LowGrayLevelZoneEmphasis"  1.000000
#    13.            "SizeZoneNonUniformity"  1.000000
#    14.   "SmallAreaHighGrayLevelEmphasis"  1.000000
#    15.                      "ZoneEntropy"  1.000000
#
# Variable Importance: NUM_NODES:
#     1.    "LargeAreaLowGrayLevelEmphasis" 651.000000 ################
#     2.   "LargeAreaHighGrayLevelEmphasis" 610.000000 ##############
#     3.           "GrayLevelNonUniformity" 582.000000 #############
#     4.        "HighGrayLevelZoneEmphasis" 578.000000 #############
#     5.                      "ZoneEntropy" 505.000000 ##########
#     6.         "LowGrayLevelZoneEmphasis" 469.000000 #########
#     7.    "SmallAreaLowGrayLevelEmphasis" 413.000000 #######
#     8.                "GrayLevelVariance" 395.000000 #######
#     9.   "SmallAreaHighGrayLevelEmphasis" 384.000000 ######
#    10.                     "ZoneVariance" 384.000000 ######
#    11. "GrayLevelNonUniformityNormalized" 367.000000 ######
#    12.  "SizeZoneNonUniformityNormalized" 243.000000 #
#    13.                "SmallAreaEmphasis" 196.000000
#    14.                   "ZonePercentage" 196.000000
#    15.            "SizeZoneNonUniformity" 188.000000
#    16.                "LargeAreaEmphasis" 185.000000
#
# Variable Importance: SUM_SCORE:
#     1.        "HighGrayLevelZoneEmphasis" 7199.068888 ################
#     2.    "LargeAreaLowGrayLevelEmphasis" 1531.441194 ###
#     3.           "GrayLevelNonUniformity" 1399.216244 ##
#     4.   "LargeAreaHighGrayLevelEmphasis" 820.077177 #
#     5.         "LowGrayLevelZoneEmphasis" 664.244869 #
#     6.                      "ZoneEntropy" 544.167223
#     7.                     "ZoneVariance" 407.263590
#     8.   "SmallAreaHighGrayLevelEmphasis" 316.876992
#     9.    "SmallAreaLowGrayLevelEmphasis" 314.061162
#    10.                "GrayLevelVariance" 286.351885
#    11. "GrayLevelNonUniformityNormalized" 265.053049
#    12.                   "ZonePercentage" 187.009683
#    13.  "SizeZoneNonUniformityNormalized" 165.099995
#    14.                "LargeAreaEmphasis" 131.822363
#    15.                "SmallAreaEmphasis" 116.606918
#    16.            "SizeZoneNonUniformity" 114.945933
#
#
#
# Loss: BINOMIAL_LOG_LIKELIHOOD
# Validation loss value: 0.226964
# Number of trees per iteration: 1
# Node format: NOT_SET
# Number of trees: 255
# Total number of nodes: 12947
#
# Number of nodes by tree:
# Count: 255 Average: 50.7725 StdDev: 9.25771
# Min: 19 Max: 63 Ignored: 0
# ----------------------------------------------
# [ 19, 21)  2   0.78%   0.78%
# [ 21, 23)  1   0.39%   1.18%
# [ 23, 25)  1   0.39%   1.57%
# [ 25, 28)  3   1.18%   2.75% #
# [ 28, 30)  2   0.78%   3.53%
# [ 30, 32)  1   0.39%   3.92%
# [ 32, 34)  5   1.96%   5.88% #
# [ 34, 37)  3   1.18%   7.06% #
# [ 37, 39)  4   1.57%   8.63% #
# [ 39, 41)  7   2.75%  11.37% ##
# [ 41, 43) 10   3.92%  15.29% ##
# [ 43, 46) 33  12.94%  28.24% ########
# [ 46, 48) 21   8.24%  36.47% #####
# [ 48, 50) 13   5.10%  41.57% ###
# [ 50, 52) 19   7.45%  49.02% #####
# [ 52, 55) 20   7.84%  56.86% #####
# [ 55, 57) 19   7.45%  64.31% #####
# [ 57, 59) 30  11.76%  76.08% #######
# [ 59, 61) 19   7.45%  83.53% #####
# [ 61, 63] 42  16.47% 100.00% ##########
#
# Depth by leafs:
# Count: 6601 Average: 4.8379 StdDev: 0.506668
# Min: 1 Max: 5 Ignored: 0
# ----------------------------------------------
# [ 1, 2)    5   0.08%   0.08%
# [ 2, 3)   65   0.98%   1.06%
# [ 3, 4)  174   2.64%   3.70%
# [ 4, 5)  507   7.68%  11.38% #
# [ 5, 5] 5850  88.62% 100.00% ##########
#
# Number of training obs by leaf:
# Count: 6601 Average: 2736.59 StdDev: 10276.1
# Min: 5 Max: 70552 Ignored: 0
# ----------------------------------------------
# [     5,  3532) 5983  90.64%  90.64% ##########
# [  3532,  7059)  138   2.09%  92.73%
# [  7059, 10587)   78   1.18%  93.91%
# [ 10587, 14114)   46   0.70%  94.61%
# [ 14114, 17642)   30   0.45%  95.06%
# [ 17642, 21169)   36   0.55%  95.61%
# [ 21169, 24696)   24   0.36%  95.97%
# [ 24696, 28224)   31   0.47%  96.44%
# [ 28224, 31751)   24   0.36%  96.80%
# [ 31751, 35279)   10   0.15%  96.96%
# [ 35279, 38806)   24   0.36%  97.32%
# [ 38806, 42333)   14   0.21%  97.53%
# [ 42333, 45861)   10   0.15%  97.68%
# [ 45861, 49388)    9   0.14%  97.82%
# [ 49388, 52916)   24   0.36%  98.18%
# [ 52916, 56443)   20   0.30%  98.49%
# [ 56443, 59970)   18   0.27%  98.76%
# [ 59970, 63498)   18   0.27%  99.03%
# [ 63498, 67025)   29   0.44%  99.47%
# [ 67025, 70552]   35   0.53% 100.00%
#
# Attribute in nodes:
# 	651 : LargeAreaLowGrayLevelEmphasis [NUMERICAL]
# 	610 : LargeAreaHighGrayLevelEmphasis [NUMERICAL]
# 	582 : GrayLevelNonUniformity [NUMERICAL]
# 	578 : HighGrayLevelZoneEmphasis [NUMERICAL]
# 	505 : ZoneEntropy [NUMERICAL]
# 	469 : LowGrayLevelZoneEmphasis [NUMERICAL]
# 	413 : SmallAreaLowGrayLevelEmphasis [NUMERICAL]
# 	395 : GrayLevelVariance [NUMERICAL]
# 	384 : ZoneVariance [NUMERICAL]
# 	384 : SmallAreaHighGrayLevelEmphasis [NUMERICAL]
# 	367 : GrayLevelNonUniformityNormalized [NUMERICAL]
# 	243 : SizeZoneNonUniformityNormalized [NUMERICAL]
# 	196 : ZonePercentage [NUMERICAL]
# 	196 : SmallAreaEmphasis [NUMERICAL]
# 	188 : SizeZoneNonUniformity [NUMERICAL]
# 	185 : LargeAreaEmphasis [NUMERICAL]
#
# Attribute in nodes with depth <= 0:
# 	58 : LargeAreaLowGrayLevelEmphasis [NUMERICAL]
# 	40 : HighGrayLevelZoneEmphasis [NUMERICAL]
# 	38 : ZoneVariance [NUMERICAL]
# 	33 : LargeAreaHighGrayLevelEmphasis [NUMERICAL]
# 	27 : SizeZoneNonUniformityNormalized [NUMERICAL]
# 	17 : GrayLevelNonUniformity [NUMERICAL]
# 	15 : GrayLevelNonUniformityNormalized [NUMERICAL]
# 	11 : SmallAreaEmphasis [NUMERICAL]
# 	8 : SmallAreaLowGrayLevelEmphasis [NUMERICAL]
# 	2 : LargeAreaEmphasis [NUMERICAL]
# 	2 : GrayLevelVariance [NUMERICAL]
# 	1 : ZoneEntropy [NUMERICAL]
# 	1 : SmallAreaHighGrayLevelEmphasis [NUMERICAL]
# 	1 : SizeZoneNonUniformity [NUMERICAL]
# 	1 : LowGrayLevelZoneEmphasis [NUMERICAL]
#
# Attribute in nodes with depth <= 1:
# 	116 : LargeAreaLowGrayLevelEmphasis [NUMERICAL]
# 	111 : LargeAreaHighGrayLevelEmphasis [NUMERICAL]
# 	77 : HighGrayLevelZoneEmphasis [NUMERICAL]
# 	70 : ZoneVariance [NUMERICAL]
# 	58 : GrayLevelNonUniformityNormalized [NUMERICAL]
# 	53 : SizeZoneNonUniformityNormalized [NUMERICAL]
# 	51 : GrayLevelNonUniformity [NUMERICAL]
# 	47 : ZoneEntropy [NUMERICAL]
# 	35 : SmallAreaLowGrayLevelEmphasis [NUMERICAL]
# 	29 : LowGrayLevelZoneEmphasis [NUMERICAL]
# 	28 : SmallAreaEmphasis [NUMERICAL]
# 	26 : GrayLevelVariance [NUMERICAL]
# 	25 : SmallAreaHighGrayLevelEmphasis [NUMERICAL]
# 	14 : ZonePercentage [NUMERICAL]
# 	10 : SizeZoneNonUniformity [NUMERICAL]
# 	10 : LargeAreaEmphasis [NUMERICAL]
#
# Attribute in nodes with depth <= 2:
# 	210 : LargeAreaHighGrayLevelEmphasis [NUMERICAL]
# 	203 : LargeAreaLowGrayLevelEmphasis [NUMERICAL]
# 	151 : HighGrayLevelZoneEmphasis [NUMERICAL]
# 	138 : GrayLevelNonUniformity [NUMERICAL]
# 	136 : ZoneEntropy [NUMERICAL]
# 	132 : ZoneVariance [NUMERICAL]
# 	113 : GrayLevelNonUniformityNormalized [NUMERICAL]
# 	109 : LowGrayLevelZoneEmphasis [NUMERICAL]
# 	96 : SmallAreaLowGrayLevelEmphasis [NUMERICAL]
# 	90 : GrayLevelVariance [NUMERICAL]
# 	88 : SizeZoneNonUniformityNormalized [NUMERICAL]
# 	80 : SmallAreaHighGrayLevelEmphasis [NUMERICAL]
# 	46 : ZonePercentage [NUMERICAL]
# 	45 : SmallAreaEmphasis [NUMERICAL]
# 	35 : LargeAreaEmphasis [NUMERICAL]
# 	33 : SizeZoneNonUniformity [NUMERICAL]
#
# Attribute in nodes with depth <= 3:
# 	377 : LargeAreaHighGrayLevelEmphasis [NUMERICAL]
# 	376 : LargeAreaLowGrayLevelEmphasis [NUMERICAL]
# 	312 : GrayLevelNonUniformity [NUMERICAL]
# 	284 : HighGrayLevelZoneEmphasis [NUMERICAL]
# 	275 : ZoneEntropy [NUMERICAL]
# 	255 : LowGrayLevelZoneEmphasis [NUMERICAL]
# 	217 : ZoneVariance [NUMERICAL]
# 	205 : SmallAreaHighGrayLevelEmphasis [NUMERICAL]
# 	204 : GrayLevelVariance [NUMERICAL]
# 	202 : GrayLevelNonUniformityNormalized [NUMERICAL]
# 	199 : SmallAreaLowGrayLevelEmphasis [NUMERICAL]
# 	140 : SizeZoneNonUniformityNormalized [NUMERICAL]
# 	109 : SmallAreaEmphasis [NUMERICAL]
# 	98 : ZonePercentage [NUMERICAL]
# 	85 : SizeZoneNonUniformity [NUMERICAL]
# 	83 : LargeAreaEmphasis [NUMERICAL]
#
# Attribute in nodes with depth <= 5:
# 	651 : LargeAreaLowGrayLevelEmphasis [NUMERICAL]
# 	610 : LargeAreaHighGrayLevelEmphasis [NUMERICAL]
# 	582 : GrayLevelNonUniformity [NUMERICAL]
# 	578 : HighGrayLevelZoneEmphasis [NUMERICAL]
# 	505 : ZoneEntropy [NUMERICAL]
# 	469 : LowGrayLevelZoneEmphasis [NUMERICAL]
# 	413 : SmallAreaLowGrayLevelEmphasis [NUMERICAL]
# 	395 : GrayLevelVariance [NUMERICAL]
# 	384 : ZoneVariance [NUMERICAL]
# 	384 : SmallAreaHighGrayLevelEmphasis [NUMERICAL]
# 	367 : GrayLevelNonUniformityNormalized [NUMERICAL]
# 	243 : SizeZoneNonUniformityNormalized [NUMERICAL]
# 	196 : ZonePercentage [NUMERICAL]
# 	196 : SmallAreaEmphasis [NUMERICAL]
# 	188 : SizeZoneNonUniformity [NUMERICAL]
# 	185 : LargeAreaEmphasis [NUMERICAL]
#
# Condition type in nodes:
# 	6346 : HigherCondition
# Condition type in nodes with depth <= 0:
# 	255 : HigherCondition
# Condition type in nodes with depth <= 1:
# 	760 : HigherCondition
# Condition type in nodes with depth <= 2:
# 	1705 : HigherCondition
# Condition type in nodes with depth <= 3:
# 	3421 : HigherCondition
# Condition type in nodes with depth <= 5:
# 	6346 : HigherCondition
#
# Training logs:
# Number of iteration to final model: 255
# 	Iter:1 train-loss:0.443853 valid-loss:0.426176  train-accuracy:0.927400 valid-accuracy:0.932546
# 	Iter:2 train-loss:0.413231 valid-loss:0.399340  train-accuracy:0.927400 valid-accuracy:0.932546
# 	Iter:3 train-loss:0.389505 valid-loss:0.378368  train-accuracy:0.927400 valid-accuracy:0.932546
# 	Iter:4 train-loss:0.371750 valid-loss:0.362943  train-accuracy:0.927400 valid-accuracy:0.932546
# 	Iter:5 train-loss:0.356003 valid-loss:0.348837  train-accuracy:0.937521 valid-accuracy:0.941565
# 	Iter:6 train-loss:0.343473 valid-loss:0.337813  train-accuracy:0.945638 valid-accuracy:0.949060
# 	Iter:16 train-loss:0.280757 valid-loss:0.283430  train-accuracy:0.956733 valid-accuracy:0.955793
# 	Iter:26 train-loss:0.257735 valid-loss:0.265392  train-accuracy:0.958879 valid-accuracy:0.958079
# 	Iter:36 train-loss:0.243268 valid-loss:0.255113  train-accuracy:0.960220 valid-accuracy:0.959604
# 	Iter:46 train-loss:0.233866 valid-loss:0.248950  train-accuracy:0.961378 valid-accuracy:0.959731
# 	Iter:56 train-loss:0.227004 valid-loss:0.245807  train-accuracy:0.963015 valid-accuracy:0.960239
# 	Iter:66 train-loss:0.221580 valid-loss:0.242370  train-accuracy:0.963834 valid-accuracy:0.959858
# 	Iter:76 train-loss:0.216382 valid-loss:0.240341  train-accuracy:0.964469 valid-accuracy:0.959858
# 	Iter:86 train-loss:0.211436 valid-loss:0.237498  train-accuracy:0.965401 valid-accuracy:0.959858
# 	Iter:96 train-loss:0.207544 valid-loss:0.236066  train-accuracy:0.965994 valid-accuracy:0.959731
# 	Iter:106 train-loss:0.204156 valid-loss:0.235015  train-accuracy:0.966573 valid-accuracy:0.960112
# 	Iter:116 train-loss:0.200061 valid-loss:0.233863  train-accuracy:0.967363 valid-accuracy:0.959985
# 	Iter:126 train-loss:0.197129 valid-loss:0.233268  train-accuracy:0.967998 valid-accuracy:0.960112
# 	Iter:136 train-loss:0.193936 valid-loss:0.232432  train-accuracy:0.968478 valid-accuracy:0.960239
# 	Iter:146 train-loss:0.190880 valid-loss:0.232054  train-accuracy:0.969170 valid-accuracy:0.960747
# 	Iter:156 train-loss:0.187485 valid-loss:0.231461  train-accuracy:0.969664 valid-accuracy:0.960620
# 	Iter:166 train-loss:0.185328 valid-loss:0.231167  train-accuracy:0.970229 valid-accuracy:0.960366
# 	Iter:176 train-loss:0.182802 valid-loss:0.230635  train-accuracy:0.970497 valid-accuracy:0.960493
# 	Iter:186 train-loss:0.181310 valid-loss:0.230345  train-accuracy:0.970935 valid-accuracy:0.960493
# 	Iter:196 train-loss:0.178586 valid-loss:0.229987  train-accuracy:0.971429 valid-accuracy:0.960239
# 	Iter:206 train-loss:0.175888 valid-loss:0.229836  train-accuracy:0.971753 valid-accuracy:0.960493
# 	Iter:216 train-loss:0.173233 valid-loss:0.229160  train-accuracy:0.972120 valid-accuracy:0.960874
# 	Iter:226 train-loss:0.171212 valid-loss:0.228760  train-accuracy:0.972600 valid-accuracy:0.960874
# 	Iter:236 train-loss:0.168446 valid-loss:0.227975  train-accuracy:0.972826 valid-accuracy:0.960747
# 	Iter:246 train-loss:0.166000 valid-loss:0.227291  train-accuracy:0.973377 valid-accuracy:0.961128
# 	Iter:256 train-loss:0.163398 valid-loss:0.226994  train-accuracy:0.973842 valid-accuracy:0.961382
# 	Iter:266 train-loss:0.162185 valid-loss:0.226976  train-accuracy:0.974082 valid-accuracy:0.960874
# 	Iter:276 train-loss:0.160200 valid-loss:0.227006  train-accuracy:0.974379 valid-accuracy:0.961128

# %%
# Model features
model.make_inspector().features()
# Out:
# ["GrayLevelNonUniformity" (1; #0),
#  "GrayLevelNonUniformityNormalized" (1; #1),
#  "GrayLevelVariance" (1; #2),
#  "HighGrayLevelZoneEmphasis" (1; #3),
#  "LargeAreaEmphasis" (1; #4),
#  "LargeAreaHighGrayLevelEmphasis" (1; #5),
#  "LargeAreaLowGrayLevelEmphasis" (1; #6),
#  "LowGrayLevelZoneEmphasis" (1; #7),
#  "SizeZoneNonUniformity" (1; #8),
#  "SizeZoneNonUniformityNormalized" (1; #9),
#  "SmallAreaEmphasis" (1; #10),
#  "SmallAreaHighGrayLevelEmphasis" (1; #11),
#  "SmallAreaLowGrayLevelEmphasis" (1; #12),
#  "ZoneEntropy" (1; #13),
#  "ZonePercentage" (1; #14),
#  "ZoneVariance" (1; #15)]

# %%
# Feature importance
model.make_inspector().variable_importances()
# Out:
# {'INV_MEAN_MIN_DEPTH': [("LargeAreaLowGrayLevelEmphasis" (1; #6),
#    0.24074425498295143),
#   ("LargeAreaHighGrayLevelEmphasis" (1; #5), 0.2303189868020131),
#   ("HighGrayLevelZoneEmphasis" (1; #3), 0.218566114242767),
#   ("ZoneVariance" (1; #15), 0.21649448153420056),
#   ("GrayLevelNonUniformity" (1; #0), 0.20808649213899993),
#   ("ZoneEntropy" (1; #13), 0.19839495027714843),
#   ("GrayLevelNonUniformityNormalized" (1; #1), 0.19705046443991173),
#   ("SizeZoneNonUniformityNormalized" (1; #9), 0.19441623958762796),
#   ("LowGrayLevelZoneEmphasis" (1; #7), 0.19247698826200013),
#   ("SmallAreaLowGrayLevelEmphasis" (1; #12), 0.19045568438907115),
#   ("GrayLevelVariance" (1; #2), 0.18935409420089042),
#   ("SmallAreaHighGrayLevelEmphasis" (1; #11), 0.18843551818070503),
#   ("SmallAreaEmphasis" (1; #10), 0.18380766201762763),
#   ("ZonePercentage" (1; #14), 0.18002791355902198),
#   ("SizeZoneNonUniformity" (1; #8), 0.17959956021079665),
#   ("LargeAreaEmphasis" (1; #4), 0.17823106315974283)],
#  'NUM_AS_ROOT': [("LargeAreaLowGrayLevelEmphasis" (1; #6), 58.0),
#   ("HighGrayLevelZoneEmphasis" (1; #3), 40.0),
#   ("ZoneVariance" (1; #15), 38.0),
#   ("LargeAreaHighGrayLevelEmphasis" (1; #5), 33.0),
#   ("SizeZoneNonUniformityNormalized" (1; #9), 27.0),
#   ("GrayLevelNonUniformity" (1; #0), 17.0),
#   ("GrayLevelNonUniformityNormalized" (1; #1), 15.0),
#   ("SmallAreaEmphasis" (1; #10), 11.0),
#   ("SmallAreaLowGrayLevelEmphasis" (1; #12), 8.0),
#   ("GrayLevelVariance" (1; #2), 2.0),
#   ("LargeAreaEmphasis" (1; #4), 2.0),
#   ("LowGrayLevelZoneEmphasis" (1; #7), 1.0),
#   ("SizeZoneNonUniformity" (1; #8), 1.0),
#   ("SmallAreaHighGrayLevelEmphasis" (1; #11), 1.0),
#   ("ZoneEntropy" (1; #13), 1.0)],
#  'SUM_SCORE': [("HighGrayLevelZoneEmphasis" (1; #3), 7199.068888428323),
#   ("LargeAreaLowGrayLevelEmphasis" (1; #6), 1531.441194113595),
#   ("GrayLevelNonUniformity" (1; #0), 1399.2162437718298),
#   ("LargeAreaHighGrayLevelEmphasis" (1; #5), 820.0771765637629),
#   ("LowGrayLevelZoneEmphasis" (1; #7), 664.2448694375549),
#   ("ZoneEntropy" (1; #13), 544.167222660281),
#   ("ZoneVariance" (1; #15), 407.2635900635411),
#   ("SmallAreaHighGrayLevelEmphasis" (1; #11), 316.8769918095212),
#   ("SmallAreaLowGrayLevelEmphasis" (1; #12), 314.06116185263807),
#   ("GrayLevelVariance" (1; #2), 286.3518852971365),
#   ("GrayLevelNonUniformityNormalized" (1; #1), 265.05304924207917),
#   ("ZonePercentage" (1; #14), 187.00968257015836),
#   ("SizeZoneNonUniformityNormalized" (1; #9), 165.0999953244936),
#   ("LargeAreaEmphasis" (1; #4), 131.8223629869808),
#   ("SmallAreaEmphasis" (1; #10), 116.60691817198193),
#   ("SizeZoneNonUniformity" (1; #8), 114.94593291837441)],
#  'NUM_NODES': [("LargeAreaLowGrayLevelEmphasis" (1; #6), 651.0),
#   ("LargeAreaHighGrayLevelEmphasis" (1; #5), 610.0),
#   ("GrayLevelNonUniformity" (1; #0), 582.0),
#   ("HighGrayLevelZoneEmphasis" (1; #3), 578.0),
#   ("ZoneEntropy" (1; #13), 505.0),
#   ("LowGrayLevelZoneEmphasis" (1; #7), 469.0),
#   ("SmallAreaLowGrayLevelEmphasis" (1; #12), 413.0),
#   ("GrayLevelVariance" (1; #2), 395.0),
#   ("SmallAreaHighGrayLevelEmphasis" (1; #11), 384.0),
#   ("ZoneVariance" (1; #15), 384.0),
#   ("GrayLevelNonUniformityNormalized" (1; #1), 367.0),
#   ("SizeZoneNonUniformityNormalized" (1; #9), 243.0),
#   ("SmallAreaEmphasis" (1; #10), 196.0),
#   ("ZonePercentage" (1; #14), 196.0),
#   ("SizeZoneNonUniformity" (1; #8), 188.0),
#   ("LargeAreaEmphasis" (1; #4), 185.0)]}

# %%
# Model self evaluation
model.make_inspector().evaluation()
# Out:
# Evaluation(num_examples=None, accuracy=0.9613820910453796, loss=0.22696439921855927, rmse=None, ndcg=None, aucs=None, auuc=None, qini=None)

# %%
logs = model.make_inspector().training_logs()

plt.figure(figsize=(12, 4))
plt.subplot(1, 2, 1)
plt.plot([log.num_trees for log in logs], [log.evaluation.accuracy for log in logs])
plt.xlabel("Number of trees")
plt.ylabel("Accuracy (out-of-bag)")
plt.subplot(1, 2, 2)
plt.plot([log.num_trees for log in logs], [log.evaluation.loss for log in logs])
plt.xlabel("Number of trees")
plt.ylabel("Logloss (out-of-bag)")
plt.show()

# %% [markdown]
# Calculate the score of our hold-out validation dataset

# %%
predictions = model.predict(val_ds)
y_true      = validation_data["label"]

from sklearn.metrics import roc_auc_score
ROC_AUC = roc_auc_score(y_true, predictions)
print("The ROC AUC score is %.5f" % ROC_AUC )
# Out:
# 12/12 [==============================] - 0s 6ms/step
# The ROC AUC score is 0.95342

# %%
# Compute binary classification metrics with sklearn
import numpy as np
from sklearn.metrics import (
    accuracy_score,
    precision_score,
    recall_score,
    f1_score,
    roc_auc_score,
    average_precision_score,
    confusion_matrix,
    classification_report,
    matthews_corrcoef,
    log_loss,
    brier_score_loss,
)

# Get predictions (probabilities or class labels)
preds = model.predict(test_ds)
# If model outputs probabilities, convert to labels by threshold 0.5
if preds.ndim == 2:
    # For TFDF classification, preds may be class probabilities with shape (N, 2)
    if preds.shape[1] == 2:
        pos_probs = preds[:, 1]
    else:
        # If single-probability column (positive class)
        pos_probs = preds[:, -1]
    y_pred = (pos_probs >= 0.5).astype(int)
else:
    # Already class labels
    y_pred = preds.astype(int)
    pos_probs = None

# Ground truth labels (must be 0/1 integers)
y_true = test_data["label"].astype(int).to_numpy()

# Core metrics
metrics = {}
metrics["accuracy"] = accuracy_score(y_true, y_pred)
metrics["precision"] = precision_score(y_true, y_pred, zero_division=0)
metrics["recall"] = recall_score(y_true, y_pred, zero_division=0)
metrics["f1"] = f1_score(y_true, y_pred, zero_division=0)
metrics["mcc"] = matthews_corrcoef(y_true, y_pred)

# Probabilistic metrics (only if we have probabilities)
if pos_probs is not None:
    metrics["roc_auc"] = roc_auc_score(y_true, pos_probs)
    metrics["pr_auc"] = average_precision_score(y_true, pos_probs)
    metrics["log_loss"] = log_loss(y_true, pos_probs, labels=[0,1])
    metrics["brier_score"] = brier_score_loss(y_true, pos_probs)

# Confusion matrix and detailed report
cm = confusion_matrix(y_true, y_pred, labels=[0,1])
report = classification_report(y_true, y_pred, digits=4)

print("Sklearn binary metrics:")
for k, v in metrics.items():
    print(f"{k}: {v:.4f}")
print("\nConfusion matrix:\n", cm)
print("\nClassification report:\n", report)
# Out:
# 23/23 [==============================] - 0s 5ms/step
# Sklearn binary metrics:
# accuracy: 0.9611
# precision: 0.8416
# recall: 0.5825
# f1: 0.6885
# mcc: 0.6814
# roc_auc: 0.9533
# pr_auc: 0.7808
# log_loss: 0.1133
# brier_score: 0.0307
#
# Confusion matrix:
#  [[20648   182]
#  [  693   967]]
#
# Classification report:
#                precision    recall  f1-score   support
#
#            0     0.9675    0.9913    0.9793     20830
#            1     0.8416    0.5825    0.6885      1660
#
#     accuracy                         0.9611     22490
#    macro avg     0.9046    0.7869    0.8339     22490
# weighted avg     0.9582    0.9611    0.9578     22490
