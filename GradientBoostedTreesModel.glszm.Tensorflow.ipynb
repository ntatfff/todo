# %%
# Import packages and modules
import numpy  as np
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow_decision_forests as tfdf

from sklearn.model_selection import train_test_split
# Out:
# 2026-05-26 17:48:22.226577: I tensorflow/core/util/port.cc:113] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2026-05-26 17:48:22.281644: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2026-05-26 17:48:23.128731: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
# Check the version of TensorFlow Decision Forests
print("Found TensorFlow Decision Forests v" + tfdf.__version__)
# Out:
# Found TensorFlow Decision Forests v1.9.1

# %%
# train/validation/test = 70/10/20
dataset = pd.read_csv('dataset/glszm/kernel5-radius5/dataset.csv')

train_data, temp_data = train_test_split(
    dataset, test_size=0.3, random_state=42
 )
validation_data, test_data = train_test_split(
    temp_data, test_size=2/3, random_state=42
 )

# %%
from sklearn.utils.class_weight import compute_class_weight

# tinh class weight tren tap train
classes = np.array([0, 1])
weights = compute_class_weight(class_weight="balanced", classes=classes, y=train_data["label"])
class_weight = {0: weights[0], 1: weights[1]}

# gan sample_weight cho tung dong
train_data["sample_weight"] = train_data["label"].map(class_weight)
validation_data["sample_weight"] = validation_data["label"].map(class_weight)
test_data["sample_weight"] = test_data["label"].map(class_weight)

# Convert the dataset into a TensorFlow dataset.
train_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    train_data, label="label", weight="sample_weight"
)         
val_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    validation_data, label="label", weight="sample_weight"
)
test_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    test_data, label="label", weight="sample_weight"
)
# Out:
# 2026-05-26 17:48:25.014576: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:984] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2026-05-26 17:48:25.015078: W tensorflow/core/common_runtime/gpu/gpu_device.cc:2251] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...

# %%
import keras

# %%
# %%time

# Train a Gradient Boosted Trees model.
model = tfdf.keras.GradientBoostedTreesModel()

# Add evaluation metrics
model.compile(
    metrics=["accuracy"]
)
model.fit(x=train_ds)

# # Train a Gradient Boosted Trees model.
# model = tfdf.keras.GradientBoostedTreesModel(num_trees=1500)
# model.fit(train_ds)
# Out:
# Use /tmp/tmp7_hy5vai as temporary training directory
# Reading training dataset...
# [WARNING 26-05-26 17:48:25.1831 UTC gradient_boosted_trees.cc:1840] "goss_alpha" set but "sampling_method" not equal to "GOSS".
# [WARNING 26-05-26 17:48:25.1832 UTC gradient_boosted_trees.cc:1851] "goss_beta" set but "sampling_method" not equal to "GOSS".
# [WARNING 26-05-26 17:48:25.1832 UTC gradient_boosted_trees.cc:1865] "selective_gradient_boosting_ratio" set but "sampling_method" not equal to "SELGB".
# Training dataset read in 0:00:03.690846. Found 78712 examples.
# Training model...
# Model trained in 0:00:14.120441
# Compiling model...
# [INFO 26-05-26 17:48:43.0336 UTC kernel.cc:1233] Loading model from path /tmp/tmp7_hy5vai/model/ with prefix 4b8a06c890e54d3c
# [INFO 26-05-26 17:48:43.0401 UTC quick_scorer_extended.cc:911] The binary was compiled without AVX2 support, but your CPU supports it. Enable it for faster model inference.
# [INFO 26-05-26 17:48:43.0405 UTC abstract_model.cc:1362] Engine "GradientBoostedTreesQuickScorerExtended" built
# [INFO 26-05-26 17:48:43.0405 UTC kernel.cc:1061] Use fast generic engine
# Model compiled.
# CPU times: user 1min 14s, sys: 2.02 s, total: 1min 16s
# Wall time: 21.2 s

# %%
# Evaluate the model
evaluate = model.evaluate(val_ds, return_dict=True)
print()

for name, value in evaluate.items():
    print(f"{name}: {value:.4f}")
# Out:
# WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 12/12 [==============================] - 3s 6ms/step - loss: 0.0000e+00 - accuracy: 0.9028
#
# loss: 0.0000
# accuracy: 0.9028

# %%
# Model Summary
model.summary()
# Out:
# Model: "gradient_boosted_trees_model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
# =================================================================
# Total params: 1 (1.00 Byte)
# Trainable params: 0 (0.00 Byte)
# Non-trainable params: 1 (1.00 Byte)
# _________________________________________________________________
# Type: "GRADIENT_BOOSTED_TREES"
# Task: CLASSIFICATION
# Label: "__LABEL"
#
# Input Features (16):
# 	GrayLevelNonUniformity
# 	GrayLevelNonUniformityNormalized
# 	GrayLevelVariance
# 	HighGrayLevelZoneEmphasis
# 	LargeAreaEmphasis
# 	LargeAreaHighGrayLevelEmphasis
# 	LargeAreaLowGrayLevelEmphasis
# 	LowGrayLevelZoneEmphasis
# 	SizeZoneNonUniformity
# 	SizeZoneNonUniformityNormalized
# 	SmallAreaEmphasis
# 	SmallAreaHighGrayLevelEmphasis
# 	SmallAreaLowGrayLevelEmphasis
# 	ZoneEntropy
# 	ZonePercentage
# 	ZoneVariance
#
# Trained with weights
#
# Variable Importance: INV_MEAN_MIN_DEPTH:
#     1.   "LargeAreaHighGrayLevelEmphasis"  0.287691 ################
#     2.        "HighGrayLevelZoneEmphasis"  0.269799 #############
#     3.           "GrayLevelNonUniformity"  0.225253 #######
#     4.    "LargeAreaLowGrayLevelEmphasis"  0.213849 #####
#     5.         "LowGrayLevelZoneEmphasis"  0.205734 ####
#     6.                     "ZoneVariance"  0.196350 ###
#     7.                      "ZoneEntropy"  0.192626 ##
#     8.                "GrayLevelVariance"  0.186934 #
#     9.    "SmallAreaLowGrayLevelEmphasis"  0.186318 #
#    10.   "SmallAreaHighGrayLevelEmphasis"  0.181549
#    11. "GrayLevelNonUniformityNormalized"  0.181029
#    12.  "SizeZoneNonUniformityNormalized"  0.178690
#    13.                "LargeAreaEmphasis"  0.177781
#    14.            "SizeZoneNonUniformity"  0.175901
#    15.                "SmallAreaEmphasis"  0.175193
#    16.                   "ZonePercentage"  0.174963
#
# Variable Importance: NUM_AS_ROOT:
#     1. "LargeAreaHighGrayLevelEmphasis" 40.000000 ################
#     2.      "HighGrayLevelZoneEmphasis" 38.000000 ###############
#     3.       "LowGrayLevelZoneEmphasis" 11.000000 ####
#     4.  "LargeAreaLowGrayLevelEmphasis" 10.000000 ###
#     5.         "GrayLevelNonUniformity"  9.000000 ###
#     6.  "SmallAreaLowGrayLevelEmphasis"  3.000000
#     7.                    "ZoneEntropy"  2.000000
#     8.              "SmallAreaEmphasis"  1.000000
#     9. "SmallAreaHighGrayLevelEmphasis"  1.000000
#    10.                   "ZoneVariance"  1.000000
#
# Variable Importance: NUM_NODES:
#     1.           "GrayLevelNonUniformity" 347.000000 ################
#     2.        "HighGrayLevelZoneEmphasis" 337.000000 ###############
#     3.    "LargeAreaLowGrayLevelEmphasis" 335.000000 ###############
#     4.   "LargeAreaHighGrayLevelEmphasis" 318.000000 ##############
#     5.         "LowGrayLevelZoneEmphasis" 255.000000 ##########
#     6.                      "ZoneEntropy" 227.000000 #########
#     7.                "GrayLevelVariance" 208.000000 ########
#     8.                     "ZoneVariance" 199.000000 #######
#     9.   "SmallAreaHighGrayLevelEmphasis" 192.000000 #######
#    10.    "SmallAreaLowGrayLevelEmphasis" 169.000000 #####
#    11. "GrayLevelNonUniformityNormalized" 141.000000 ####
#    12.  "SizeZoneNonUniformityNormalized" 92.000000 #
#    13.            "SizeZoneNonUniformity" 90.000000 #
#    14.                "LargeAreaEmphasis" 70.000000
#    15.                "SmallAreaEmphasis" 70.000000
#    16.                   "ZonePercentage" 63.000000
#
# Variable Importance: SUM_SCORE:
#     1.        "HighGrayLevelZoneEmphasis" 31484.610923 ################
#     2.           "GrayLevelNonUniformity" 9729.944998 ####
#     3.   "LargeAreaHighGrayLevelEmphasis" 8762.954798 ####
#     4.    "LargeAreaLowGrayLevelEmphasis" 4492.399481 ##
#     5.                      "ZoneEntropy" 3173.212736 #
#     6.         "LowGrayLevelZoneEmphasis" 2255.788438 #
#     7.    "SmallAreaLowGrayLevelEmphasis" 1831.182826
#     8.  "SizeZoneNonUniformityNormalized" 1733.611738
#     9.                     "ZoneVariance" 1389.620021
#    10.                "GrayLevelVariance" 1104.888119
#    11.   "SmallAreaHighGrayLevelEmphasis" 988.787989
#    12. "GrayLevelNonUniformityNormalized" 795.217953
#    13.            "SizeZoneNonUniformity" 486.052767
#    14.                   "ZonePercentage" 279.355812
#    15.                "SmallAreaEmphasis" 278.171011
#    16.                "LargeAreaEmphasis" 187.360535
#
#
#
# Loss: BINOMIAL_LOG_LIKELIHOOD
# Validation loss value: 0.591326
# Number of trees per iteration: 1
# Node format: NOT_SET
# Number of trees: 116
# Total number of nodes: 6342
#
# Number of nodes by tree:
# Count: 116 Average: 54.6724 StdDev: 7.70107
# Min: 33 Max: 63 Ignored: 0
# ----------------------------------------------
# [ 33, 34)  2   1.72%   1.72% #
# [ 34, 36)  1   0.86%   2.59%
# [ 36, 37)  0   0.00%   2.59%
# [ 37, 39)  0   0.00%   2.59%
# [ 39, 40)  0   0.00%   2.59%
# [ 40, 42)  3   2.59%   5.17% #
# [ 42, 43)  0   0.00%   5.17%
# [ 43, 45)  8   6.90%  12.07% ####
# [ 45, 46)  9   7.76%  19.83% ####
# [ 46, 48)  7   6.03%  25.86% ###
# [ 48, 50)  3   2.59%  28.45% #
# [ 50, 51)  0   0.00%  28.45%
# [ 51, 53)  2   1.72%  30.17% #
# [ 53, 54)  8   6.90%  37.07% ####
# [ 54, 56)  9   7.76%  44.83% ####
# [ 56, 57)  0   0.00%  44.83%
# [ 57, 59) 13  11.21%  56.03% ######
# [ 59, 60) 12  10.34%  66.38% #####
# [ 60, 62) 17  14.66%  81.03% ########
# [ 62, 63] 22  18.97% 100.00% ##########
#
# Depth by leafs:
# Count: 3229 Average: 4.88789 StdDev: 0.407204
# Min: 2 Max: 5 Ignored: 0
# ----------------------------------------------
# [ 2, 3)   14   0.43%   0.43%
# [ 3, 4)   65   2.01%   2.45%
# [ 4, 5)  190   5.88%   8.33% #
# [ 5, 5] 2960  91.67% 100.00% ##########
#
# Number of training obs by leaf:
# Count: 3229 Average: 2544.89 StdDev: 7847.23
# Min: 5 Max: 67441 Ignored: 0
# ----------------------------------------------
# [     5,  3376) 2763  85.57%  85.57% ##########
# [  3376,  6748)  182   5.64%  91.20% #
# [  6748, 10120)   77   2.38%  93.59%
# [ 10120, 13492)   42   1.30%  94.89%
# [ 13492, 16864)   37   1.15%  96.04%
# [ 16864, 20236)   26   0.81%  96.84%
# [ 20236, 23607)   27   0.84%  97.68%
# [ 23607, 26979)    8   0.25%  97.93%
# [ 26979, 30351)    9   0.28%  98.20%
# [ 30351, 33723)    4   0.12%  98.33%
# [ 33723, 37095)    5   0.15%  98.48%
# [ 37095, 40467)    3   0.09%  98.58%
# [ 40467, 43839)    2   0.06%  98.64%
# [ 43839, 47210)    6   0.19%  98.82%
# [ 47210, 50582)    7   0.22%  99.04%
# [ 50582, 53954)    2   0.06%  99.10%
# [ 53954, 57326)   10   0.31%  99.41%
# [ 57326, 60698)    5   0.15%  99.57%
# [ 60698, 64070)    4   0.12%  99.69%
# [ 64070, 67441]   10   0.31% 100.00%
#
# Attribute in nodes:
# 	347 : GrayLevelNonUniformity [NUMERICAL]
# 	337 : HighGrayLevelZoneEmphasis [NUMERICAL]
# 	335 : LargeAreaLowGrayLevelEmphasis [NUMERICAL]
# 	318 : LargeAreaHighGrayLevelEmphasis [NUMERICAL]
# 	255 : LowGrayLevelZoneEmphasis [NUMERICAL]
# 	227 : ZoneEntropy [NUMERICAL]
# 	208 : GrayLevelVariance [NUMERICAL]
# 	199 : ZoneVariance [NUMERICAL]
# 	192 : SmallAreaHighGrayLevelEmphasis [NUMERICAL]
# 	169 : SmallAreaLowGrayLevelEmphasis [NUMERICAL]
# 	141 : GrayLevelNonUniformityNormalized [NUMERICAL]
# 	92 : SizeZoneNonUniformityNormalized [NUMERICAL]
# 	90 : SizeZoneNonUniformity [NUMERICAL]
# 	70 : SmallAreaEmphasis [NUMERICAL]
# 	70 : LargeAreaEmphasis [NUMERICAL]
# 	63 : ZonePercentage [NUMERICAL]
#
# Attribute in nodes with depth <= 0:
# 	40 : LargeAreaHighGrayLevelEmphasis [NUMERICAL]
# 	38 : HighGrayLevelZoneEmphasis [NUMERICAL]
# 	11 : LowGrayLevelZoneEmphasis [NUMERICAL]
# 	10 : LargeAreaLowGrayLevelEmphasis [NUMERICAL]
# 	9 : GrayLevelNonUniformity [NUMERICAL]
# 	3 : SmallAreaLowGrayLevelEmphasis [NUMERICAL]
# 	2 : ZoneEntropy [NUMERICAL]
# 	1 : ZoneVariance [NUMERICAL]
# 	1 : SmallAreaHighGrayLevelEmphasis [NUMERICAL]
# 	1 : SmallAreaEmphasis [NUMERICAL]
#
# Attribute in nodes with depth <= 1:
# 	80 : LargeAreaHighGrayLevelEmphasis [NUMERICAL]
# 	67 : HighGrayLevelZoneEmphasis [NUMERICAL]
# 	52 : GrayLevelNonUniformity [NUMERICAL]
# 	31 : LargeAreaLowGrayLevelEmphasis [NUMERICAL]
# 	23 : LowGrayLevelZoneEmphasis [NUMERICAL]
# 	20 : ZoneVariance [NUMERICAL]
# 	15 : ZoneEntropy [NUMERICAL]
# 	13 : GrayLevelVariance [NUMERICAL]
# 	12 : SmallAreaLowGrayLevelEmphasis [NUMERICAL]
# 	9 : LargeAreaEmphasis [NUMERICAL]
# 	8 : SizeZoneNonUniformityNormalized [NUMERICAL]
# 	7 : GrayLevelNonUniformityNormalized [NUMERICAL]
# 	4 : SmallAreaHighGrayLevelEmphasis [NUMERICAL]
# 	3 : SmallAreaEmphasis [NUMERICAL]
# 	2 : ZonePercentage [NUMERICAL]
# 	2 : SizeZoneNonUniformity [NUMERICAL]
#
# Attribute in nodes with depth <= 2:
# 	125 : HighGrayLevelZoneEmphasis [NUMERICAL]
# 	112 : LargeAreaHighGrayLevelEmphasis [NUMERICAL]
# 	90 : GrayLevelNonUniformity [NUMERICAL]
# 	86 : LargeAreaLowGrayLevelEmphasis [NUMERICAL]
# 	75 : LowGrayLevelZoneEmphasis [NUMERICAL]
# 	64 : ZoneVariance [NUMERICAL]
# 	52 : ZoneEntropy [NUMERICAL]
# 	39 : GrayLevelVariance [NUMERICAL]
# 	36 : SmallAreaLowGrayLevelEmphasis [NUMERICAL]
# 	26 : GrayLevelNonUniformityNormalized [NUMERICAL]
# 	24 : SmallAreaHighGrayLevelEmphasis [NUMERICAL]
# 	20 : LargeAreaEmphasis [NUMERICAL]
# 	17 : SizeZoneNonUniformityNormalized [NUMERICAL]
# 	12 : SizeZoneNonUniformity [NUMERICAL]
# 	11 : ZonePercentage [NUMERICAL]
# 	9 : SmallAreaEmphasis [NUMERICAL]
#
# Attribute in nodes with depth <= 3:
# 	199 : HighGrayLevelZoneEmphasis [NUMERICAL]
# 	186 : LargeAreaHighGrayLevelEmphasis [NUMERICAL]
# 	178 : GrayLevelNonUniformity [NUMERICAL]
# 	172 : LargeAreaLowGrayLevelEmphasis [NUMERICAL]
# 	145 : LowGrayLevelZoneEmphasis [NUMERICAL]
# 	107 : GrayLevelVariance [NUMERICAL]
# 	105 : ZoneVariance [NUMERICAL]
# 	103 : ZoneEntropy [NUMERICAL]
# 	97 : SmallAreaHighGrayLevelEmphasis [NUMERICAL]
# 	93 : SmallAreaLowGrayLevelEmphasis [NUMERICAL]
# 	57 : GrayLevelNonUniformityNormalized [NUMERICAL]
# 	44 : SizeZoneNonUniformityNormalized [NUMERICAL]
# 	43 : SizeZoneNonUniformity [NUMERICAL]
# 	36 : ZonePercentage [NUMERICAL]
# 	35 : LargeAreaEmphasis [NUMERICAL]
# 	33 : SmallAreaEmphasis [NUMERICAL]
#
# Attribute in nodes with depth <= 5:
# 	347 : GrayLevelNonUniformity [NUMERICAL]
# 	337 : HighGrayLevelZoneEmphasis [NUMERICAL]
# 	335 : LargeAreaLowGrayLevelEmphasis [NUMERICAL]
# 	318 : LargeAreaHighGrayLevelEmphasis [NUMERICAL]
# 	255 : LowGrayLevelZoneEmphasis [NUMERICAL]
# 	227 : ZoneEntropy [NUMERICAL]
# 	208 : GrayLevelVariance [NUMERICAL]
# 	199 : ZoneVariance [NUMERICAL]
# 	192 : SmallAreaHighGrayLevelEmphasis [NUMERICAL]
# 	169 : SmallAreaLowGrayLevelEmphasis [NUMERICAL]
# 	141 : GrayLevelNonUniformityNormalized [NUMERICAL]
# 	92 : SizeZoneNonUniformityNormalized [NUMERICAL]
# 	90 : SizeZoneNonUniformity [NUMERICAL]
# 	70 : SmallAreaEmphasis [NUMERICAL]
# 	70 : LargeAreaEmphasis [NUMERICAL]
# 	63 : ZonePercentage [NUMERICAL]
#
# Condition type in nodes:
# 	3113 : HigherCondition
# Condition type in nodes with depth <= 0:
# 	116 : HigherCondition
# Condition type in nodes with depth <= 1:
# 	348 : HigherCondition
# Condition type in nodes with depth <= 2:
# 	798 : HigherCondition
# Condition type in nodes with depth <= 3:
# 	1633 : HigherCondition
# Condition type in nodes with depth <= 5:
# 	3113 : HigherCondition
#
# Training logs:
# Number of iteration to final model: 116
# 	Iter:1 train-loss:1.286036 valid-loss:1.290987  train-accuracy:0.826381 valid-accuracy:0.807359
# 	Iter:2 train-loss:1.204375 valid-loss:1.213518  train-accuracy:0.827368 valid-accuracy:0.812575
# 	Iter:3 train-loss:1.132869 valid-loss:1.145092  train-accuracy:0.840060 valid-accuracy:0.824831
# 	Iter:4 train-loss:1.073116 valid-loss:1.087812  train-accuracy:0.842374 valid-accuracy:0.826717
# 	Iter:5 train-loss:1.021357 valid-loss:1.037230  train-accuracy:0.842834 valid-accuracy:0.828957
# 	Iter:6 train-loss:0.973404 valid-loss:0.991633  train-accuracy:0.849783 valid-accuracy:0.834240
# 	Iter:16 train-loss:0.719128 valid-loss:0.751209  train-accuracy:0.864273 valid-accuracy:0.853565
# 	Iter:26 train-loss:0.624708 valid-loss:0.669272  train-accuracy:0.873887 valid-accuracy:0.862945
# 	Iter:36 train-loss:0.579725 valid-loss:0.637973  train-accuracy:0.879733 valid-accuracy:0.866163
# 	Iter:46 train-loss:0.551507 valid-loss:0.618844  train-accuracy:0.885645 valid-accuracy:0.867028
# 	Iter:56 train-loss:0.532901 valid-loss:0.609917  train-accuracy:0.889020 valid-accuracy:0.866270
# 	Iter:66 train-loss:0.517930 valid-loss:0.604503  train-accuracy:0.892902 valid-accuracy:0.870193
# 	Iter:76 train-loss:0.501859 valid-loss:0.600613  train-accuracy:0.895256 valid-accuracy:0.872856
# 	Iter:86 train-loss:0.490645 valid-loss:0.598221  train-accuracy:0.897863 valid-accuracy:0.874963
# 	Iter:96 train-loss:0.475484 valid-loss:0.594531  train-accuracy:0.902404 valid-accuracy:0.872962
# 	Iter:106 train-loss:0.464457 valid-loss:0.592945  train-accuracy:0.905546 valid-accuracy:0.870873
# 	Iter:116 train-loss:0.455682 valid-loss:0.591326  train-accuracy:0.908611 valid-accuracy:0.875149
# 	Iter:126 train-loss:0.446931 valid-loss:0.594221  train-accuracy:0.911144 valid-accuracy:0.872636
# 	Iter:136 train-loss:0.439829 valid-loss:0.593503  train-accuracy:0.912737 valid-accuracy:0.874391
# 	Iter:146 train-loss:0.430341 valid-loss:0.593621  train-accuracy:0.915149 valid-accuracy:0.872725

# %%
# Model features
model.make_inspector().features()
# Out:
# ["GrayLevelNonUniformity" (1; #0),
#  "GrayLevelNonUniformityNormalized" (1; #1),
#  "GrayLevelVariance" (1; #2),
#  "HighGrayLevelZoneEmphasis" (1; #3),
#  "LargeAreaEmphasis" (1; #4),
#  "LargeAreaHighGrayLevelEmphasis" (1; #5),
#  "LargeAreaLowGrayLevelEmphasis" (1; #6),
#  "LowGrayLevelZoneEmphasis" (1; #7),
#  "SizeZoneNonUniformity" (1; #8),
#  "SizeZoneNonUniformityNormalized" (1; #9),
#  "SmallAreaEmphasis" (1; #10),
#  "SmallAreaHighGrayLevelEmphasis" (1; #11),
#  "SmallAreaLowGrayLevelEmphasis" (1; #12),
#  "ZoneEntropy" (1; #13),
#  "ZonePercentage" (1; #14),
#  "ZoneVariance" (1; #15)]

# %%
# Feature importance
model.make_inspector().variable_importances()
# Out:
# {'INV_MEAN_MIN_DEPTH': [("LargeAreaHighGrayLevelEmphasis" (1; #5),
#    0.2876908661111692),
#   ("HighGrayLevelZoneEmphasis" (1; #3), 0.2697990514364677),
#   ("GrayLevelNonUniformity" (1; #0), 0.22525327802020914),
#   ("LargeAreaLowGrayLevelEmphasis" (1; #6), 0.21384929935323274),
#   ("LowGrayLevelZoneEmphasis" (1; #7), 0.205734470934058),
#   ("ZoneVariance" (1; #15), 0.19634968745901826),
#   ("ZoneEntropy" (1; #13), 0.19262550769234488),
#   ("GrayLevelVariance" (1; #2), 0.18693415199100816),
#   ("SmallAreaLowGrayLevelEmphasis" (1; #12), 0.1863183713884715),
#   ("SmallAreaHighGrayLevelEmphasis" (1; #11), 0.18154918135185186),
#   ("GrayLevelNonUniformityNormalized" (1; #1), 0.18102850703353293),
#   ("SizeZoneNonUniformityNormalized" (1; #9), 0.17868957993150442),
#   ("LargeAreaEmphasis" (1; #4), 0.1777805258246488),
#   ("SizeZoneNonUniformity" (1; #8), 0.17590074290405763),
#   ("SmallAreaEmphasis" (1; #10), 0.17519283719460027),
#   ("ZonePercentage" (1; #14), 0.17496276733830518)],
#  'SUM_SCORE': [("HighGrayLevelZoneEmphasis" (1; #3), 31484.610923066193),
#   ("GrayLevelNonUniformity" (1; #0), 9729.944997869234),
#   ("LargeAreaHighGrayLevelEmphasis" (1; #5), 8762.954798228844),
#   ("LargeAreaLowGrayLevelEmphasis" (1; #6), 4492.399480856842),
#   ("ZoneEntropy" (1; #13), 3173.21273646834),
#   ("LowGrayLevelZoneEmphasis" (1; #7), 2255.7884375438516),
#   ("SmallAreaLowGrayLevelEmphasis" (1; #12), 1831.18282599789),
#   ("SizeZoneNonUniformityNormalized" (1; #9), 1733.6117384411161),
#   ("ZoneVariance" (1; #15), 1389.6200205106613),
#   ("GrayLevelVariance" (1; #2), 1104.8881191381124),
#   ("SmallAreaHighGrayLevelEmphasis" (1; #11), 988.7879891129706),
#   ("GrayLevelNonUniformityNormalized" (1; #1), 795.2179525491869),
#   ("SizeZoneNonUniformity" (1; #8), 486.0527672622062),
#   ("ZonePercentage" (1; #14), 279.35581215368046),
#   ("SmallAreaEmphasis" (1; #10), 278.17101069814896),
#   ("LargeAreaEmphasis" (1; #4), 187.3605352018105)],
#  'NUM_AS_ROOT': [("LargeAreaHighGrayLevelEmphasis" (1; #5), 40.0),
#   ("HighGrayLevelZoneEmphasis" (1; #3), 38.0),
#   ("LowGrayLevelZoneEmphasis" (1; #7), 11.0),
#   ("LargeAreaLowGrayLevelEmphasis" (1; #6), 10.0),
#   ("GrayLevelNonUniformity" (1; #0), 9.0),
#   ("SmallAreaLowGrayLevelEmphasis" (1; #12), 3.0),
#   ("ZoneEntropy" (1; #13), 2.0),
#   ("SmallAreaEmphasis" (1; #10), 1.0),
#   ("SmallAreaHighGrayLevelEmphasis" (1; #11), 1.0),
#   ("ZoneVariance" (1; #15), 1.0)],
#  'NUM_NODES': [("GrayLevelNonUniformity" (1; #0), 347.0),
#   ("HighGrayLevelZoneEmphasis" (1; #3), 337.0),
#   ("LargeAreaLowGrayLevelEmphasis" (1; #6), 335.0),
#   ("LargeAreaHighGrayLevelEmphasis" (1; #5), 318.0),
#   ("LowGrayLevelZoneEmphasis" (1; #7), 255.0),
#   ("ZoneEntropy" (1; #13), 227.0),
#   ("GrayLevelVariance" (1; #2), 208.0),
#   ("ZoneVariance" (1; #15), 199.0),
#   ("SmallAreaHighGrayLevelEmphasis" (1; #11), 192.0),
#   ("SmallAreaLowGrayLevelEmphasis" (1; #12), 169.0),
#   ("GrayLevelNonUniformityNormalized" (1; #1), 141.0),
#   ("SizeZoneNonUniformityNormalized" (1; #9), 92.0),
#   ("SizeZoneNonUniformity" (1; #8), 90.0),
#   ("LargeAreaEmphasis" (1; #4), 70.0),
#   ("SmallAreaEmphasis" (1; #10), 70.0),
#   ("ZonePercentage" (1; #14), 63.0)]}

# %%
# Model self evaluation
model.make_inspector().evaluation()
# Out:
# Evaluation(num_examples=None, accuracy=0.8751488924026489, loss=0.5913260579109192, rmse=None, ndcg=None, aucs=None, auuc=None, qini=None)

# %%
logs = model.make_inspector().training_logs()

plt.figure(figsize=(12, 4))
plt.subplot(1, 2, 1)
plt.plot([log.num_trees for log in logs], [log.evaluation.accuracy for log in logs])
plt.xlabel("Number of trees")
plt.ylabel("Accuracy (out-of-bag)")
plt.subplot(1, 2, 2)
plt.plot([log.num_trees for log in logs], [log.evaluation.loss for log in logs])
plt.xlabel("Number of trees")
plt.ylabel("Logloss (out-of-bag)")
plt.show()

# %% [markdown]
# Calculate the score of our hold-out validation dataset

# %%
predictions = model.predict(val_ds)
y_true      = validation_data["label"]

from sklearn.metrics import roc_auc_score
ROC_AUC = roc_auc_score(y_true, predictions)
print("The ROC AUC score is %.5f" % ROC_AUC )
# Out:
#  1/12 [=>............................] - ETA: 0s
# 12/12 [==============================] - 0s 5ms/step
# The ROC AUC score is 0.95361

# %%
# Compute binary classification metrics with sklearn
import numpy as np
from sklearn.metrics import (
    accuracy_score,
    precision_score,
    recall_score,
    f1_score,
    roc_auc_score,
    average_precision_score,
    confusion_matrix,
    classification_report,
    matthews_corrcoef,
    log_loss,
    brier_score_loss,
)

# Get predictions (probabilities or class labels)
preds = model.predict(test_ds)
# If model outputs probabilities, convert to labels by threshold 0.5
if preds.ndim == 2:
    # For TFDF classification, preds may be class probabilities with shape (N, 2)
    if preds.shape[1] == 2:
        pos_probs = preds[:, 1]
    else:
        # If single-probability column (positive class)
        pos_probs = preds[:, -1]
    y_pred = (pos_probs >= 0.5).astype(int)
else:
    # Already class labels
    y_pred = preds.astype(int)
    pos_probs = None

# Ground truth labels (must be 0/1 integers)
y_true = test_data["label"].astype(int).to_numpy()

# Core metrics
metrics = {}
metrics["accuracy"] = accuracy_score(y_true, y_pred)
metrics["precision"] = precision_score(y_true, y_pred, zero_division=0)
metrics["recall"] = recall_score(y_true, y_pred, zero_division=0)
metrics["f1"] = f1_score(y_true, y_pred, zero_division=0)
metrics["mcc"] = matthews_corrcoef(y_true, y_pred)

# Probabilistic metrics (only if we have probabilities)
if pos_probs is not None:
    metrics["roc_auc"] = roc_auc_score(y_true, pos_probs)
    metrics["pr_auc"] = average_precision_score(y_true, pos_probs)
    metrics["log_loss"] = log_loss(y_true, pos_probs, labels=[0,1])
    metrics["brier_score"] = brier_score_loss(y_true, pos_probs)

# Confusion matrix and detailed report
cm = confusion_matrix(y_true, y_pred, labels=[0,1])
report = classification_report(y_true, y_pred, digits=4)

print("Sklearn binary metrics:")
for k, v in metrics.items():
    print(f"{k}: {v:.4f}")
print("\nConfusion matrix:\n", cm)
print("\nClassification report:\n", report)
# Out:
# 23/23 [==============================] - 0s 5ms/step
# Sklearn binary metrics:
# accuracy: 0.8996
# precision: 0.4135
# recall: 0.8596
# f1: 0.5584
# mcc: 0.5531
# roc_auc: 0.9512
# pr_auc: 0.7562
# log_loss: 0.2510
# brier_score: 0.0746
#
# Confusion matrix:
#  [[18806  2024]
#  [  233  1427]]
#
# Classification report:
#                precision    recall  f1-score   support
#
#            0     0.9878    0.9028    0.9434     20830
#            1     0.4135    0.8596    0.5584      1660
#
#     accuracy                         0.8996     22490
#    macro avg     0.7006    0.8812    0.7509     22490
# weighted avg     0.9454    0.8996    0.9150     22490
