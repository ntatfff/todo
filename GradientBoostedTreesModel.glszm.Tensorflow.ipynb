# %%
# Import packages and modules
import numpy  as np
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow_decision_forests as tfdf

from sklearn.model_selection import train_test_split

# %%
# Check the version of TensorFlow Decision Forests
print("Found TensorFlow Decision Forests v" + tfdf.__version__)
# Out:
# Found TensorFlow Decision Forests v1.9.1

# %%
# train/validation/test = 70/10/20
dataset = pd.read_csv('dataset/glszm/kernel5-radius5/dataset.200p.csv')

train_data, temp_data = train_test_split(
    dataset, test_size=0.3, random_state=42
 )
validation_data, test_data = train_test_split(
    temp_data, test_size=2/3, random_state=42
 )

# %%
from sklearn.utils.class_weight import compute_class_weight

# tinh class weight tren tap train
classes = np.array([0, 1])
weights = compute_class_weight(class_weight="balanced", classes=classes, y=train_data["label"])
class_weight = {0: weights[0], 1: weights[1]}

# gan sample_weight cho tung dong
train_data["sample_weight"] = train_data["label"].map(class_weight)
validation_data["sample_weight"] = validation_data["label"].map(class_weight)
test_data["sample_weight"] = test_data["label"].map(class_weight)

# Convert the dataset into a TensorFlow dataset.
train_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    train_data, label="label", weight="sample_weight"
)         
val_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    validation_data, label="label", weight="sample_weight"
)
test_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    test_data, label="label", weight="sample_weight"
)

# %%
import keras

# %%
# %%time

# Train a Gradient Boosted Trees model.
model = tfdf.keras.GradientBoostedTreesModel()

# Add evaluation metrics
model.compile(
    metrics=["accuracy"]
)
model.fit(x=train_ds)

# # Train a Gradient Boosted Trees model.
# model = tfdf.keras.GradientBoostedTreesModel(num_trees=1500)
# model.fit(train_ds)
# Out:
# Use /tmp/tmp91sd6byd as temporary training directory
# Reading training dataset...
# [WARNING 26-05-27 15:54:18.9501 UTC gradient_boosted_trees.cc:1840] "goss_alpha" set but "sampling_method" not equal to "GOSS".
# [WARNING 26-05-27 15:54:18.9501 UTC gradient_boosted_trees.cc:1851] "goss_beta" set but "sampling_method" not equal to "GOSS".
# [WARNING 26-05-27 15:54:18.9501 UTC gradient_boosted_trees.cc:1865] "selective_gradient_boosting_ratio" set but "sampling_method" not equal to "SELGB".
# Training dataset read in 0:00:01.965967. Found 157360 examples.
# Training model...
# Model trained in 0:00:40.026188
# Compiling model...
# Model compiled.
# CPU times: user 4min 45s, sys: 3.74 s, total: 4min 49s
# Wall time: 42.1 s
# [INFO 26-05-27 15:55:00.9341 UTC kernel.cc:1233] Loading model from path /tmp/tmp91sd6byd/model/ with prefix 53cb0f1f224f4834
# [INFO 26-05-27 15:55:00.9482 UTC quick_scorer_extended.cc:911] The binary was compiled without AVX2 support, but your CPU supports it. Enable it for faster model inference.
# [INFO 26-05-27 15:55:00.9495 UTC abstract_model.cc:1362] Engine "GradientBoostedTreesQuickScorerExtended" built
# [INFO 26-05-27 15:55:00.9496 UTC kernel.cc:1061] Use fast generic engine

# %%
# Evaluate the model
evaluate = model.evaluate(val_ds, return_dict=True)
print()

for name, value in evaluate.items():
    print(f"{name}: {value:.4f}")
# Out:
# WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 23/23 [==============================] - 0s 5ms/step - loss: 0.0000e+00 - accuracy: 0.8843
#
# loss: 0.0000
# accuracy: 0.8843

# %%
# Model Summary
model.summary()
# Out:
# Model: "gradient_boosted_trees_model_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
# =================================================================
# Total params: 1 (1.00 Byte)
# Trainable params: 0 (0.00 Byte)
# Non-trainable params: 1 (1.00 Byte)
# _________________________________________________________________
# Type: "GRADIENT_BOOSTED_TREES"
# Task: CLASSIFICATION
# Label: "__LABEL"
#
# Input Features (16):
# 	GrayLevelNonUniformity
# 	GrayLevelNonUniformityNormalized
# 	GrayLevelVariance
# 	HighGrayLevelZoneEmphasis
# 	LargeAreaEmphasis
# 	LargeAreaHighGrayLevelEmphasis
# 	LargeAreaLowGrayLevelEmphasis
# 	LowGrayLevelZoneEmphasis
# 	SizeZoneNonUniformity
# 	SizeZoneNonUniformityNormalized
# 	SmallAreaEmphasis
# 	SmallAreaHighGrayLevelEmphasis
# 	SmallAreaLowGrayLevelEmphasis
# 	ZoneEntropy
# 	ZonePercentage
# 	ZoneVariance
#
# Trained with weights
#
# Variable Importance: INV_MEAN_MIN_DEPTH:
#     1.   "LargeAreaHighGrayLevelEmphasis"  0.282442 ################
#     2.           "GrayLevelNonUniformity"  0.227148 #######
#     3.        "HighGrayLevelZoneEmphasis"  0.213572 #####
#     4.    "LargeAreaLowGrayLevelEmphasis"  0.207705 ####
#     5.                     "ZoneVariance"  0.202636 ###
#     6.         "LowGrayLevelZoneEmphasis"  0.198224 ###
#     7.    "SmallAreaLowGrayLevelEmphasis"  0.191494 ##
#     8.                "GrayLevelVariance"  0.189726 #
#     9.   "SmallAreaHighGrayLevelEmphasis"  0.187384 #
#    10.                      "ZoneEntropy"  0.185625 #
#    11. "GrayLevelNonUniformityNormalized"  0.183277 #
#    12.  "SizeZoneNonUniformityNormalized"  0.182744
#    13.                "LargeAreaEmphasis"  0.180991
#    14.                "SmallAreaEmphasis"  0.179632
#    15.            "SizeZoneNonUniformity"  0.177383
#    16.                   "ZonePercentage"  0.176610
#
# Variable Importance: NUM_AS_ROOT:
#     1.   "LargeAreaHighGrayLevelEmphasis" 105.000000 ################
#     2.           "GrayLevelNonUniformity" 42.000000 ######
#     3.        "HighGrayLevelZoneEmphasis" 31.000000 ####
#     4.         "LowGrayLevelZoneEmphasis" 28.000000 ####
#     5.    "LargeAreaLowGrayLevelEmphasis" 19.000000 ##
#     6.    "SmallAreaLowGrayLevelEmphasis" 15.000000 ##
#     7.  "SizeZoneNonUniformityNormalized"  7.000000
#     8.                     "ZoneVariance"  6.000000
#     9. "GrayLevelNonUniformityNormalized"  4.000000
#    10.                "GrayLevelVariance"  4.000000
#    11.                "SmallAreaEmphasis"  4.000000
#    12.                "LargeAreaEmphasis"  3.000000
#    13.                      "ZoneEntropy"  3.000000
#    14.   "SmallAreaHighGrayLevelEmphasis"  2.000000
#    15.            "SizeZoneNonUniformity"  1.000000
#
# Variable Importance: NUM_NODES:
#     1.   "LargeAreaHighGrayLevelEmphasis" 852.000000 ################
#     2.        "HighGrayLevelZoneEmphasis" 735.000000 #############
#     3.    "LargeAreaLowGrayLevelEmphasis" 702.000000 ############
#     4.           "GrayLevelNonUniformity" 634.000000 ##########
#     5.                     "ZoneVariance" 585.000000 #########
#     6.         "LowGrayLevelZoneEmphasis" 525.000000 ########
#     7.   "SmallAreaHighGrayLevelEmphasis" 494.000000 #######
#     8.    "SmallAreaLowGrayLevelEmphasis" 443.000000 ######
#     9.                      "ZoneEntropy" 406.000000 #####
#    10.                "GrayLevelVariance" 384.000000 ####
#    11. "GrayLevelNonUniformityNormalized" 366.000000 ####
#    12.  "SizeZoneNonUniformityNormalized" 280.000000 ##
#    13.                "LargeAreaEmphasis" 256.000000 #
#    14.            "SizeZoneNonUniformity" 238.000000 #
#    15.                "SmallAreaEmphasis" 226.000000 #
#    16.                   "ZonePercentage" 184.000000
#
# Variable Importance: SUM_SCORE:
#     1.        "HighGrayLevelZoneEmphasis" 44732.654644 ################
#     2.           "GrayLevelNonUniformity" 22589.645035 #######
#     3.    "LargeAreaLowGrayLevelEmphasis" 14906.171145 #####
#     4.  "SizeZoneNonUniformityNormalized" 14481.858530 ####
#     5.         "LowGrayLevelZoneEmphasis" 7148.279758 ##
#     6.   "LargeAreaHighGrayLevelEmphasis" 5569.486907 #
#     7.   "SmallAreaHighGrayLevelEmphasis" 5432.860726 #
#     8.    "SmallAreaLowGrayLevelEmphasis" 4925.501580 #
#     9.                     "ZoneVariance" 4441.290247 #
#    10.                      "ZoneEntropy" 3381.132703
#    11.                "GrayLevelVariance" 2416.818489
#    12.            "SizeZoneNonUniformity" 1393.488413
#    13. "GrayLevelNonUniformityNormalized" 1375.102389
#    14.                   "ZonePercentage" 1169.430644
#    15.                "LargeAreaEmphasis" 847.218037
#    16.                "SmallAreaEmphasis" 763.292573
#
#
#
# Loss: BINOMIAL_LOG_LIKELIHOOD
# Validation loss value: 0.64207
# Number of trees per iteration: 1
# Node format: NOT_SET
# Number of trees: 274
# Total number of nodes: 14894
#
# Number of nodes by tree:
# Count: 274 Average: 54.3577 StdDev: 6.78958
# Min: 35 Max: 63 Ignored: 0
# ----------------------------------------------
# [ 35, 36)  1   0.36%   0.36%
# [ 36, 37)  0   0.00%   0.36%
# [ 37, 39)  0   0.00%   0.36%
# [ 39, 40)  3   1.09%   1.46% #
# [ 40, 42)  5   1.82%   3.28% #
# [ 42, 43)  0   0.00%   3.28%
# [ 43, 45)  6   2.19%   5.47% #
# [ 45, 46) 23   8.39%  13.87% ####
# [ 46, 48) 18   6.57%  20.44% ###
# [ 48, 49)  0   0.00%  20.44%
# [ 49, 50) 30  10.95%  31.39% #####
# [ 50, 52) 20   7.30%  38.69% ####
# [ 52, 53)  0   0.00%  38.69%
# [ 53, 55) 21   7.66%  46.35% ####
# [ 55, 56) 26   9.49%  55.84% #####
# [ 56, 58) 19   6.93%  62.77% ###
# [ 58, 59)  0   0.00%  62.77%
# [ 59, 61) 26   9.49%  72.26% #####
# [ 61, 62) 20   7.30%  79.56% ####
# [ 62, 63] 56  20.44% 100.00% ##########
#
# Depth by leafs:
# Count: 7584 Average: 4.88344 StdDev: 0.415128
# Min: 2 Max: 5 Ignored: 0
# ----------------------------------------------
# [ 2, 3)   37   0.49%   0.49%
# [ 3, 4)  152   2.00%   2.49%
# [ 4, 5)  469   6.18%   8.68% #
# [ 5, 5] 6926  91.32% 100.00% ##########
#
# Number of training obs by leaf:
# Count: 7584 Average: 5118.21 StdDev: 17232.4
# Min: 5 Max: 140462 Ignored: 0
# ----------------------------------------------
# [      5,   7027) 6663  87.86%  87.86% ##########
# [   7027,  14050)  316   4.17%  92.02%
# [  14050,  21073)  142   1.87%  93.90%
# [  21073,  28096)   92   1.21%  95.11%
# [  28096,  35119)   69   0.91%  96.02%
# [  35119,  42142)   38   0.50%  96.52%
# [  42142,  49165)   18   0.24%  96.76%
# [  49165,  56188)   20   0.26%  97.02%
# [  56188,  63211)   22   0.29%  97.31%
# [  63211,  70234)   28   0.37%  97.68%
# [  70234,  77256)   17   0.22%  97.90%
# [  77256,  84279)   27   0.36%  98.26%
# [  84279,  91302)   18   0.24%  98.50%
# [  91302,  98325)   27   0.36%  98.85%
# [  98325, 105348)   10   0.13%  98.98%
# [ 105348, 112371)   17   0.22%  99.21%
# [ 112371, 119394)   22   0.29%  99.50%
# [ 119394, 126417)   14   0.18%  99.68%
# [ 126417, 133440)   14   0.18%  99.87%
# [ 133440, 140462]   10   0.13% 100.00%
#
# Attribute in nodes:
# 	852 : LargeAreaHighGrayLevelEmphasis [NUMERICAL]
# 	735 : HighGrayLevelZoneEmphasis [NUMERICAL]
# 	702 : LargeAreaLowGrayLevelEmphasis [NUMERICAL]
# 	634 : GrayLevelNonUniformity [NUMERICAL]
# 	585 : ZoneVariance [NUMERICAL]
# 	525 : LowGrayLevelZoneEmphasis [NUMERICAL]
# 	494 : SmallAreaHighGrayLevelEmphasis [NUMERICAL]
# 	443 : SmallAreaLowGrayLevelEmphasis [NUMERICAL]
# 	406 : ZoneEntropy [NUMERICAL]
# 	384 : GrayLevelVariance [NUMERICAL]
# 	366 : GrayLevelNonUniformityNormalized [NUMERICAL]
# 	280 : SizeZoneNonUniformityNormalized [NUMERICAL]
# 	256 : LargeAreaEmphasis [NUMERICAL]
# 	238 : SizeZoneNonUniformity [NUMERICAL]
# 	226 : SmallAreaEmphasis [NUMERICAL]
# 	184 : ZonePercentage [NUMERICAL]
#
# Attribute in nodes with depth <= 0:
# 	105 : LargeAreaHighGrayLevelEmphasis [NUMERICAL]
# 	42 : GrayLevelNonUniformity [NUMERICAL]
# 	31 : HighGrayLevelZoneEmphasis [NUMERICAL]
# 	28 : LowGrayLevelZoneEmphasis [NUMERICAL]
# 	19 : LargeAreaLowGrayLevelEmphasis [NUMERICAL]
# 	15 : SmallAreaLowGrayLevelEmphasis [NUMERICAL]
# 	7 : SizeZoneNonUniformityNormalized [NUMERICAL]
# 	6 : ZoneVariance [NUMERICAL]
# 	4 : SmallAreaEmphasis [NUMERICAL]
# 	4 : GrayLevelVariance [NUMERICAL]
# 	4 : GrayLevelNonUniformityNormalized [NUMERICAL]
# 	3 : ZoneEntropy [NUMERICAL]
# 	3 : LargeAreaEmphasis [NUMERICAL]
# 	2 : SmallAreaHighGrayLevelEmphasis [NUMERICAL]
# 	1 : SizeZoneNonUniformity [NUMERICAL]
#
# Attribute in nodes with depth <= 1:
# 	226 : LargeAreaHighGrayLevelEmphasis [NUMERICAL]
# 	124 : GrayLevelNonUniformity [NUMERICAL]
# 	81 : HighGrayLevelZoneEmphasis [NUMERICAL]
# 	68 : LargeAreaLowGrayLevelEmphasis [NUMERICAL]
# 	67 : ZoneVariance [NUMERICAL]
# 	47 : LowGrayLevelZoneEmphasis [NUMERICAL]
# 	41 : SmallAreaLowGrayLevelEmphasis [NUMERICAL]
# 	35 : GrayLevelVariance [NUMERICAL]
# 	28 : SmallAreaHighGrayLevelEmphasis [NUMERICAL]
# 	20 : SmallAreaEmphasis [NUMERICAL]
# 	19 : SizeZoneNonUniformityNormalized [NUMERICAL]
# 	18 : LargeAreaEmphasis [NUMERICAL]
# 	17 : ZoneEntropy [NUMERICAL]
# 	14 : GrayLevelNonUniformityNormalized [NUMERICAL]
# 	12 : SizeZoneNonUniformity [NUMERICAL]
# 	5 : ZonePercentage [NUMERICAL]
#
# Attribute in nodes with depth <= 2:
# 	340 : LargeAreaHighGrayLevelEmphasis [NUMERICAL]
# 	210 : HighGrayLevelZoneEmphasis [NUMERICAL]
# 	179 : GrayLevelNonUniformity [NUMERICAL]
# 	165 : ZoneVariance [NUMERICAL]
# 	161 : LargeAreaLowGrayLevelEmphasis [NUMERICAL]
# 	110 : LowGrayLevelZoneEmphasis [NUMERICAL]
# 	103 : SmallAreaLowGrayLevelEmphasis [NUMERICAL]
# 	100 : GrayLevelVariance [NUMERICAL]
# 	89 : ZoneEntropy [NUMERICAL]
# 	88 : SmallAreaHighGrayLevelEmphasis [NUMERICAL]
# 	73 : GrayLevelNonUniformityNormalized [NUMERICAL]
# 	66 : SizeZoneNonUniformityNormalized [NUMERICAL]
# 	60 : LargeAreaEmphasis [NUMERICAL]
# 	55 : SmallAreaEmphasis [NUMERICAL]
# 	42 : ZonePercentage [NUMERICAL]
# 	40 : SizeZoneNonUniformity [NUMERICAL]
#
# Attribute in nodes with depth <= 3:
# 	513 : LargeAreaHighGrayLevelEmphasis [NUMERICAL]
# 	414 : HighGrayLevelZoneEmphasis [NUMERICAL]
# 	370 : LargeAreaLowGrayLevelEmphasis [NUMERICAL]
# 	345 : ZoneVariance [NUMERICAL]
# 	333 : GrayLevelNonUniformity [NUMERICAL]
# 	260 : LowGrayLevelZoneEmphasis [NUMERICAL]
# 	235 : SmallAreaHighGrayLevelEmphasis [NUMERICAL]
# 	227 : SmallAreaLowGrayLevelEmphasis [NUMERICAL]
# 	214 : GrayLevelVariance [NUMERICAL]
# 	188 : ZoneEntropy [NUMERICAL]
# 	182 : GrayLevelNonUniformityNormalized [NUMERICAL]
# 	147 : SizeZoneNonUniformityNormalized [NUMERICAL]
# 	127 : LargeAreaEmphasis [NUMERICAL]
# 	112 : SmallAreaEmphasis [NUMERICAL]
# 	95 : SizeZoneNonUniformity [NUMERICAL]
# 	85 : ZonePercentage [NUMERICAL]
#
# Attribute in nodes with depth <= 5:
# 	852 : LargeAreaHighGrayLevelEmphasis [NUMERICAL]
# 	735 : HighGrayLevelZoneEmphasis [NUMERICAL]
# 	702 : LargeAreaLowGrayLevelEmphasis [NUMERICAL]
# 	634 : GrayLevelNonUniformity [NUMERICAL]
# 	585 : ZoneVariance [NUMERICAL]
# 	525 : LowGrayLevelZoneEmphasis [NUMERICAL]
# 	494 : SmallAreaHighGrayLevelEmphasis [NUMERICAL]
# 	443 : SmallAreaLowGrayLevelEmphasis [NUMERICAL]
# 	406 : ZoneEntropy [NUMERICAL]
# 	384 : GrayLevelVariance [NUMERICAL]
# 	366 : GrayLevelNonUniformityNormalized [NUMERICAL]
# 	280 : SizeZoneNonUniformityNormalized [NUMERICAL]
# 	256 : LargeAreaEmphasis [NUMERICAL]
# 	238 : SizeZoneNonUniformity [NUMERICAL]
# 	226 : SmallAreaEmphasis [NUMERICAL]
# 	184 : ZonePercentage [NUMERICAL]
#
# Condition type in nodes:
# 	7310 : HigherCondition
# Condition type in nodes with depth <= 0:
# 	274 : HigherCondition
# Condition type in nodes with depth <= 1:
# 	822 : HigherCondition
# Condition type in nodes with depth <= 2:
# 	1881 : HigherCondition
# Condition type in nodes with depth <= 3:
# 	3847 : HigherCondition
# Condition type in nodes with depth <= 5:
# 	7310 : HigherCondition
#
# Training logs:
# Number of iteration to final model: 274
# 	Iter:1 train-loss:1.294964 valid-loss:1.294744  train-accuracy:0.815703 valid-accuracy:0.812479
# 	Iter:2 train-loss:1.219935 valid-loss:1.219817  train-accuracy:0.820814 valid-accuracy:0.822542
# 	Iter:3 train-loss:1.156204 valid-loss:1.156297  train-accuracy:0.823424 valid-accuracy:0.819050
# 	Iter:4 train-loss:1.102005 valid-loss:1.102535  train-accuracy:0.826379 valid-accuracy:0.828225
# 	Iter:5 train-loss:1.049684 valid-loss:1.051998  train-accuracy:0.833489 valid-accuracy:0.832592
# 	Iter:6 train-loss:1.004850 valid-loss:1.009755  train-accuracy:0.839768 valid-accuracy:0.832621
# 	Iter:16 train-loss:0.780660 valid-loss:0.801138  train-accuracy:0.852408 valid-accuracy:0.838839
# 	Iter:26 train-loss:0.694121 valid-loss:0.727753  train-accuracy:0.859814 valid-accuracy:0.846638
# 	Iter:36 train-loss:0.654462 valid-loss:0.700546  train-accuracy:0.864988 valid-accuracy:0.847463
# 	Iter:46 train-loss:0.629130 valid-loss:0.683602  train-accuracy:0.868908 valid-accuracy:0.850856
# 	Iter:56 train-loss:0.612282 valid-loss:0.674638  train-accuracy:0.872145 valid-accuracy:0.852558
# 	Iter:66 train-loss:0.598659 valid-loss:0.667882  train-accuracy:0.874857 valid-accuracy:0.853190
# 	Iter:76 train-loss:0.586570 valid-loss:0.662657  train-accuracy:0.877858 valid-accuracy:0.854478
# 	Iter:86 train-loss:0.576936 valid-loss:0.659491  train-accuracy:0.880419 valid-accuracy:0.857217
# 	Iter:96 train-loss:0.567491 valid-loss:0.655945  train-accuracy:0.882677 valid-accuracy:0.859565
# 	Iter:106 train-loss:0.558088 valid-loss:0.653387  train-accuracy:0.884954 valid-accuracy:0.858815
# 	Iter:116 train-loss:0.550147 valid-loss:0.651827  train-accuracy:0.886570 valid-accuracy:0.856592
# 	Iter:126 train-loss:0.542219 valid-loss:0.650079  train-accuracy:0.887983 valid-accuracy:0.857559
# 	Iter:136 train-loss:0.536439 valid-loss:0.649414  train-accuracy:0.889354 valid-accuracy:0.856925
# 	Iter:146 train-loss:0.530583 valid-loss:0.648630  train-accuracy:0.890852 valid-accuracy:0.857788
# 	Iter:156 train-loss:0.522625 valid-loss:0.647036  train-accuracy:0.893480 valid-accuracy:0.858178
# 	Iter:166 train-loss:0.518018 valid-loss:0.646711  train-accuracy:0.894443 valid-accuracy:0.860020
# 	Iter:176 train-loss:0.509543 valid-loss:0.644735  train-accuracy:0.896926 valid-accuracy:0.859973
# 	Iter:186 train-loss:0.505269 valid-loss:0.645313  train-accuracy:0.898272 valid-accuracy:0.860156
# 	Iter:196 train-loss:0.500709 valid-loss:0.644984  train-accuracy:0.899991 valid-accuracy:0.860202
# 	Iter:206 train-loss:0.494720 valid-loss:0.644360  train-accuracy:0.901922 valid-accuracy:0.858831
# 	Iter:216 train-loss:0.489690 valid-loss:0.644114  train-accuracy:0.903252 valid-accuracy:0.859152
# 	Iter:226 train-loss:0.484802 valid-loss:0.643279  train-accuracy:0.904828 valid-accuracy:0.858622
# 	Iter:236 train-loss:0.480623 valid-loss:0.643279  train-accuracy:0.905817 valid-accuracy:0.860533
# 	Iter:246 train-loss:0.475573 valid-loss:0.643251  train-accuracy:0.907457 valid-accuracy:0.860751
# 	Iter:256 train-loss:0.470401 valid-loss:0.642561  train-accuracy:0.908659 valid-accuracy:0.861476
# 	Iter:266 train-loss:0.466248 valid-loss:0.642918  train-accuracy:0.910020 valid-accuracy:0.861314
# 	Iter:276 train-loss:0.462862 valid-loss:0.642402  train-accuracy:0.910607 valid-accuracy:0.862500
# 	Iter:286 train-loss:0.458433 valid-loss:0.642814  train-accuracy:0.911749 valid-accuracy:0.860646
# 	Iter:296 train-loss:0.454292 valid-loss:0.642325  train-accuracy:0.912708 valid-accuracy:0.861026

# %%
# Model features
model.make_inspector().features()
# Out:
# ["GrayLevelNonUniformity" (1; #0),
#  "GrayLevelNonUniformityNormalized" (1; #1),
#  "GrayLevelVariance" (1; #2),
#  "HighGrayLevelZoneEmphasis" (1; #3),
#  "LargeAreaEmphasis" (1; #4),
#  "LargeAreaHighGrayLevelEmphasis" (1; #5),
#  "LargeAreaLowGrayLevelEmphasis" (1; #6),
#  "LowGrayLevelZoneEmphasis" (1; #7),
#  "SizeZoneNonUniformity" (1; #8),
#  "SizeZoneNonUniformityNormalized" (1; #9),
#  "SmallAreaEmphasis" (1; #10),
#  "SmallAreaHighGrayLevelEmphasis" (1; #11),
#  "SmallAreaLowGrayLevelEmphasis" (1; #12),
#  "ZoneEntropy" (1; #13),
#  "ZonePercentage" (1; #14),
#  "ZoneVariance" (1; #15)]

# %%
# Feature importance
model.make_inspector().variable_importances()
# Out:
# {'INV_MEAN_MIN_DEPTH': [("LargeAreaHighGrayLevelEmphasis" (1; #5),
#    0.28244233801196084),
#   ("GrayLevelNonUniformity" (1; #0), 0.2271477651552083),
#   ("HighGrayLevelZoneEmphasis" (1; #3), 0.21357229495441157),
#   ("LargeAreaLowGrayLevelEmphasis" (1; #6), 0.207704855240223),
#   ("ZoneVariance" (1; #15), 0.20263600515127164),
#   ("LowGrayLevelZoneEmphasis" (1; #7), 0.19822397507639944),
#   ("SmallAreaLowGrayLevelEmphasis" (1; #12), 0.191493587793814),
#   ("GrayLevelVariance" (1; #2), 0.18972619352708847),
#   ("SmallAreaHighGrayLevelEmphasis" (1; #11), 0.187384142654252),
#   ("ZoneEntropy" (1; #13), 0.185625104532945),
#   ("GrayLevelNonUniformityNormalized" (1; #1), 0.18327706490390736),
#   ("SizeZoneNonUniformityNormalized" (1; #9), 0.18274356493089366),
#   ("LargeAreaEmphasis" (1; #4), 0.18099063744747748),
#   ("SmallAreaEmphasis" (1; #10), 0.1796315256916739),
#   ("SizeZoneNonUniformity" (1; #8), 0.17738323298341355),
#   ("ZonePercentage" (1; #14), 0.17661003948032475)],
#  'SUM_SCORE': [("HighGrayLevelZoneEmphasis" (1; #3), 44732.65464439289),
#   ("GrayLevelNonUniformity" (1; #0), 22589.645034791552),
#   ("LargeAreaLowGrayLevelEmphasis" (1; #6), 14906.17114463611),
#   ("SizeZoneNonUniformityNormalized" (1; #9), 14481.858529907842),
#   ("LowGrayLevelZoneEmphasis" (1; #7), 7148.279757524136),
#   ("LargeAreaHighGrayLevelEmphasis" (1; #5), 5569.486906701033),
#   ("SmallAreaHighGrayLevelEmphasis" (1; #11), 5432.8607256436735),
#   ("SmallAreaLowGrayLevelEmphasis" (1; #12), 4925.501580385237),
#   ("ZoneVariance" (1; #15), 4441.290246669501),
#   ("ZoneEntropy" (1; #13), 3381.1327026702925),
#   ("GrayLevelVariance" (1; #2), 2416.818489434304),
#   ("SizeZoneNonUniformity" (1; #8), 1393.488412545796),
#   ("GrayLevelNonUniformityNormalized" (1; #1), 1375.102389390166),
#   ("ZonePercentage" (1; #14), 1169.4306443975254),
#   ("LargeAreaEmphasis" (1; #4), 847.2180368406432),
#   ("SmallAreaEmphasis" (1; #10), 763.2925725052564)],
#  'NUM_AS_ROOT': [("LargeAreaHighGrayLevelEmphasis" (1; #5), 105.0),
#   ("GrayLevelNonUniformity" (1; #0), 42.0),
#   ("HighGrayLevelZoneEmphasis" (1; #3), 31.0),
#   ("LowGrayLevelZoneEmphasis" (1; #7), 28.0),
#   ("LargeAreaLowGrayLevelEmphasis" (1; #6), 19.0),
#   ("SmallAreaLowGrayLevelEmphasis" (1; #12), 15.0),
#   ("SizeZoneNonUniformityNormalized" (1; #9), 7.0),
#   ("ZoneVariance" (1; #15), 6.0),
#   ("GrayLevelNonUniformityNormalized" (1; #1), 4.0),
#   ("GrayLevelVariance" (1; #2), 4.0),
#   ("SmallAreaEmphasis" (1; #10), 4.0),
#   ("LargeAreaEmphasis" (1; #4), 3.0),
#   ("ZoneEntropy" (1; #13), 3.0),
#   ("SmallAreaHighGrayLevelEmphasis" (1; #11), 2.0),
#   ("SizeZoneNonUniformity" (1; #8), 1.0)],
#  'NUM_NODES': [("LargeAreaHighGrayLevelEmphasis" (1; #5), 852.0),
#   ("HighGrayLevelZoneEmphasis" (1; #3), 735.0),
#   ("LargeAreaLowGrayLevelEmphasis" (1; #6), 702.0),
#   ("GrayLevelNonUniformity" (1; #0), 634.0),
#   ("ZoneVariance" (1; #15), 585.0),
#   ("LowGrayLevelZoneEmphasis" (1; #7), 525.0),
#   ("SmallAreaHighGrayLevelEmphasis" (1; #11), 494.0),
#   ("SmallAreaLowGrayLevelEmphasis" (1; #12), 443.0),
#   ("ZoneEntropy" (1; #13), 406.0),
#   ("GrayLevelVariance" (1; #2), 384.0),
#   ("GrayLevelNonUniformityNormalized" (1; #1), 366.0),
#   ("SizeZoneNonUniformityNormalized" (1; #9), 280.0),
#   ("LargeAreaEmphasis" (1; #4), 256.0),
#   ("SizeZoneNonUniformity" (1; #8), 238.0),
#   ("SmallAreaEmphasis" (1; #10), 226.0),
#   ("ZonePercentage" (1; #14), 184.0)]}

# %%
# Model self evaluation
model.make_inspector().evaluation()
# Out:
# Evaluation(num_examples=None, accuracy=0.8619241714477539, loss=0.6420697569847107, rmse=None, ndcg=None, aucs=None, auuc=None, qini=None)

# %%
logs = model.make_inspector().training_logs()

plt.figure(figsize=(12, 4))
plt.subplot(1, 2, 1)
plt.plot([log.num_trees for log in logs], [log.evaluation.accuracy for log in logs])
plt.xlabel("Number of trees")
plt.ylabel("Accuracy (out-of-bag)")
plt.subplot(1, 2, 2)
plt.plot([log.num_trees for log in logs], [log.evaluation.loss for log in logs])
plt.xlabel("Number of trees")
plt.ylabel("Logloss (out-of-bag)")
plt.show()

# %% [markdown]
# Calculate the score of our hold-out validation dataset

# %%
predictions = model.predict(val_ds)
y_true      = validation_data["label"]

from sklearn.metrics import roc_auc_score
ROC_AUC = roc_auc_score(y_true, predictions)
print("The ROC AUC score is %.5f" % ROC_AUC )
# Out:
# 23/23 [==============================] - 0s 8ms/step
# The ROC AUC score is 0.94332

# %%
# Compute binary classification metrics with sklearn
import numpy as np
from sklearn.metrics import (
    accuracy_score,
    precision_score,
    recall_score,
    f1_score,
    roc_auc_score,
    average_precision_score,
    confusion_matrix,
    classification_report,
    matthews_corrcoef,
    log_loss,
    brier_score_loss,
)

# Get predictions (probabilities or class labels)
preds = model.predict(test_ds)
# If model outputs probabilities, convert to labels by threshold 0.5
if preds.ndim == 2:
    # For TFDF classification, preds may be class probabilities with shape (N, 2)
    if preds.shape[1] == 2:
        pos_probs = preds[:, 1]
    else:
        # If single-probability column (positive class)
        pos_probs = preds[:, -1]
    y_pred = (pos_probs >= 0.5).astype(int)
else:
    # Already class labels
    y_pred = preds.astype(int)
    pos_probs = None

# Ground truth labels (must be 0/1 integers)
y_true = test_data["label"].astype(int).to_numpy()

# Core metrics
metrics = {}
metrics["accuracy"] = accuracy_score(y_true, y_pred)
metrics["precision"] = precision_score(y_true, y_pred, zero_division=0)
metrics["recall"] = recall_score(y_true, y_pred, zero_division=0)
metrics["f1"] = f1_score(y_true, y_pred, zero_division=0)
metrics["mcc"] = matthews_corrcoef(y_true, y_pred)

# Probabilistic metrics (only if we have probabilities)
if pos_probs is not None:
    metrics["roc_auc"] = roc_auc_score(y_true, pos_probs)
    metrics["pr_auc"] = average_precision_score(y_true, pos_probs)
    metrics["log_loss"] = log_loss(y_true, pos_probs, labels=[0,1])
    metrics["brier_score"] = brier_score_loss(y_true, pos_probs)

# Confusion matrix and detailed report
cm = confusion_matrix(y_true, y_pred, labels=[0,1])
report = classification_report(y_true, y_pred, digits=4)

print("Sklearn binary metrics:")
for k, v in metrics.items():
    print(f"{k}: {v:.4f}")
print("\nConfusion matrix:\n", cm)
print("\nClassification report:\n", report)
# Out:
# 45/45 [==============================] - 0s 5ms/step
# Sklearn binary metrics:
# accuracy: 0.8823
# precision: 0.3431
# recall: 0.8351
# f1: 0.4863
# mcc: 0.4876
# roc_auc: 0.9386
# pr_auc: 0.6607
# log_loss: 0.2704
# brier_score: 0.0839
#
# Confusion matrix:
#  [[37161  4799]
#  [  495  2506]]
#
# Classification report:
#                precision    recall  f1-score   support
#
#            0     0.9869    0.8856    0.9335     41960
#            1     0.3431    0.8351    0.4863      3001
#
#     accuracy                         0.8823     44961
#    macro avg     0.6650    0.8603    0.7099     44961
# weighted avg     0.9439    0.8823    0.9037     44961
