# %%
# Import packages and modules
import numpy  as np
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow_decision_forests as tfdf

from sklearn.model_selection import train_test_split

# %%
# Check the version of TensorFlow Decision Forests
print("Found TensorFlow Decision Forests v" + tfdf.__version__)
# Out:
# Found TensorFlow Decision Forests v1.9.1

# %%
# train/validation/test = 70/10/20
dataset = pd.read_csv('dataset/glrlm/kernel5-radius5/dataset.200p.csv')

train_data, temp_data = train_test_split(
    dataset, test_size=0.3, random_state=42
 )
validation_data, test_data = train_test_split(
    temp_data, test_size=2/3, random_state=42
 )

# %%
from sklearn.utils.class_weight import compute_class_weight

# tinh class weight tren tap train
classes = np.array([0, 1])
weights = compute_class_weight(class_weight="balanced", classes=classes, y=train_data["label"])
class_weight = {0: weights[0], 1: weights[1]}

# gan sample_weight cho tung dong
train_data["sample_weight"] = train_data["label"].map(class_weight)
validation_data["sample_weight"] = validation_data["label"].map(class_weight)
test_data["sample_weight"] = test_data["label"].map(class_weight)

# Convert the dataset into a TensorFlow dataset.
train_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    train_data, label="label", weight="sample_weight"
)         
val_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    validation_data, label="label", weight="sample_weight"
)
test_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    test_data, label="label", weight="sample_weight"
)

# %%
import keras

# %%
# %%time

# Train a Gradient Boosted Trees model.
model = tfdf.keras.GradientBoostedTreesModel()

# Add evaluation metrics
model.compile(
    metrics=["accuracy"]
)
model.fit(x=train_ds)

# # Train a Gradient Boosted Trees model.
# model = tfdf.keras.GradientBoostedTreesModel(num_trees=1500)
# model.fit(train_ds)
# Out:
# Use /tmp/tmp6uaqooix as temporary training directory
# Reading training dataset...
# [WARNING 26-05-27 16:01:47.0572 UTC gradient_boosted_trees.cc:1840] "goss_alpha" set but "sampling_method" not equal to "GOSS".
# [WARNING 26-05-27 16:01:47.0572 UTC gradient_boosted_trees.cc:1851] "goss_beta" set but "sampling_method" not equal to "GOSS".
# [WARNING 26-05-27 16:01:47.0573 UTC gradient_boosted_trees.cc:1865] "selective_gradient_boosting_ratio" set but "sampling_method" not equal to "SELGB".
# Training dataset read in 0:00:00.856213. Found 156683 examples.
# Training model...
# Model trained in 0:00:33.612813
# Compiling model...
# Model compiled.
# CPU times: user 4min 2s, sys: 3.15 s, total: 4min 5s
# Wall time: 34.6 s
# [INFO 26-05-27 16:02:21.5193 UTC kernel.cc:1233] Loading model from path /tmp/tmp6uaqooix/model/ with prefix 39683a0311904a5f
# [INFO 26-05-27 16:02:21.5314 UTC quick_scorer_extended.cc:911] The binary was compiled without AVX2 support, but your CPU supports it. Enable it for faster model inference.
# [INFO 26-05-27 16:02:21.5325 UTC abstract_model.cc:1362] Engine "GradientBoostedTreesQuickScorerExtended" built
# [INFO 26-05-27 16:02:21.5325 UTC kernel.cc:1061] Use fast generic engine

# %%
# Evaluate the model
evaluate = model.evaluate(val_ds, return_dict=True)
print()

for name, value in evaluate.items():
    print(f"{name}: {value:.4f}")
# Out:
# WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 23/23 [==============================] - 0s 6ms/step - loss: 0.0000e+00 - accuracy: 0.8953
#
# loss: 0.0000
# accuracy: 0.8953

# %%
# Model Summary
model.summary()
# Out:
# Model: "gradient_boosted_trees_model_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
# =================================================================
# Total params: 1 (1.00 Byte)
# Trainable params: 0 (0.00 Byte)
# Non-trainable params: 1 (1.00 Byte)
# _________________________________________________________________
# Type: "GRADIENT_BOOSTED_TREES"
# Task: CLASSIFICATION
# Label: "__LABEL"
#
# Input Features (16):
# 	GrayLevelNonUniformity
# 	GrayLevelNonUniformityNormalized
# 	GrayLevelVariance
# 	HighGrayLevelRunEmphasis
# 	LongRunEmphasis
# 	LongRunHighGrayLevelEmphasis
# 	LongRunLowGrayLevelEmphasis
# 	LowGrayLevelRunEmphasis
# 	RunEntropy
# 	RunLengthNonUniformity
# 	RunLengthNonUniformityNormalized
# 	RunPercentage
# 	RunVariance
# 	ShortRunEmphasis
# 	ShortRunHighGrayLevelEmphasis
# 	ShortRunLowGrayLevelEmphasis
#
# Trained with weights
#
# Variable Importance: INV_MEAN_MIN_DEPTH:
#     1.     "LongRunHighGrayLevelEmphasis"  0.247970 ################
#     2.           "GrayLevelNonUniformity"  0.229170 ###########
#     3.                       "RunEntropy"  0.207579 ######
#     4.     "ShortRunLowGrayLevelEmphasis"  0.206873 ######
#     5. "RunLengthNonUniformityNormalized"  0.204307 ######
#     6.                      "RunVariance"  0.199195 ####
#     7.    "ShortRunHighGrayLevelEmphasis"  0.193618 ###
#     8.          "LowGrayLevelRunEmphasis"  0.192851 ###
#     9.                "GrayLevelVariance"  0.192075 ###
#    10.      "LongRunLowGrayLevelEmphasis"  0.189492 ##
#    11.                 "ShortRunEmphasis"  0.188799 ##
#    12.         "HighGrayLevelRunEmphasis"  0.187428 ##
#    13.           "RunLengthNonUniformity"  0.182900 #
#    14. "GrayLevelNonUniformityNormalized"  0.182666 #
#    15.                  "LongRunEmphasis"  0.180142
#    16.                    "RunPercentage"  0.177301
#
# Variable Importance: NUM_AS_ROOT:
#     1.           "GrayLevelNonUniformity" 44.000000 ################
#     2.     "LongRunHighGrayLevelEmphasis" 43.000000 ###############
#     3.     "ShortRunLowGrayLevelEmphasis" 26.000000 #########
#     4. "RunLengthNonUniformityNormalized" 25.000000 ########
#     5.          "LowGrayLevelRunEmphasis" 16.000000 #####
#     6.                       "RunEntropy" 15.000000 #####
#     7.                      "RunVariance" 12.000000 ####
#     8.           "RunLengthNonUniformity" 11.000000 ###
#     9.      "LongRunLowGrayLevelEmphasis"  8.000000 ##
#    10.    "ShortRunHighGrayLevelEmphasis"  8.000000 ##
#    11.                 "ShortRunEmphasis"  7.000000 ##
#    12.         "HighGrayLevelRunEmphasis"  4.000000 #
#    13.                    "RunPercentage"  3.000000
#    14. "GrayLevelNonUniformityNormalized"  2.000000
#    15.                "GrayLevelVariance"  1.000000
#
# Variable Importance: NUM_NODES:
#     1.     "LongRunHighGrayLevelEmphasis" 837.000000 ################
#     2.                       "RunEntropy" 589.000000 ##########
#     3.           "GrayLevelNonUniformity" 555.000000 #########
#     4.                "GrayLevelVariance" 494.000000 #######
#     5.     "ShortRunLowGrayLevelEmphasis" 431.000000 ######
#     6.    "ShortRunHighGrayLevelEmphasis" 412.000000 #####
#     7.      "LongRunLowGrayLevelEmphasis" 381.000000 #####
#     8.                      "RunVariance" 367.000000 ####
#     9.         "HighGrayLevelRunEmphasis" 364.000000 ####
#    10.          "LowGrayLevelRunEmphasis" 292.000000 ###
#    11. "RunLengthNonUniformityNormalized" 279.000000 ##
#    12.                 "ShortRunEmphasis" 263.000000 ##
#    13. "GrayLevelNonUniformityNormalized" 252.000000 ##
#    14.                  "LongRunEmphasis" 191.000000
#    15.           "RunLengthNonUniformity" 173.000000
#    16.                    "RunPercentage" 165.000000
#
# Variable Importance: SUM_SCORE:
#     1.     "ShortRunLowGrayLevelEmphasis" 27796.595901 ################
#     2.     "LongRunHighGrayLevelEmphasis" 27378.306104 ###############
#     3.    "ShortRunHighGrayLevelEmphasis" 17297.528537 #########
#     4.          "LowGrayLevelRunEmphasis" 16204.198545 #########
#     5.                       "RunEntropy" 14151.556394 #######
#     6.           "GrayLevelNonUniformity" 9188.821410 #####
#     7.                      "RunVariance" 6841.406700 ###
#     8.                "GrayLevelVariance" 3899.384516 #
#     9.         "HighGrayLevelRunEmphasis" 3848.846777 #
#    10.      "LongRunLowGrayLevelEmphasis" 2631.873285 #
#    11.                 "ShortRunEmphasis" 2218.610639
#    12. "RunLengthNonUniformityNormalized" 1980.081957
#    13.           "RunLengthNonUniformity" 1162.424876
#    14. "GrayLevelNonUniformityNormalized" 1031.518581
#    15.                  "LongRunEmphasis" 744.249454
#    16.                    "RunPercentage" 685.365278
#
#
#
# Loss: BINOMIAL_LOG_LIKELIHOOD
# Validation loss value: 0.591107
# Number of trees per iteration: 1
# Node format: NOT_SET
# Number of trees: 225
# Total number of nodes: 12315
#
# Number of nodes by tree:
# Count: 225 Average: 54.7333 StdDev: 7.38045
# Min: 29 Max: 63 Ignored: 0
# ----------------------------------------------
# [ 29, 30)  1   0.44%   0.44%
# [ 30, 32)  1   0.44%   0.89%
# [ 32, 34)  0   0.00%   0.89%
# [ 34, 36)  1   0.44%   1.33%
# [ 36, 37)  0   0.00%   1.33%
# [ 37, 39)  3   1.33%   2.67% #
# [ 39, 41)  1   0.44%   3.11%
# [ 41, 43)  6   2.67%   5.78% #
# [ 43, 44)  5   2.22%   8.00% #
# [ 44, 46) 12   5.33%  13.33% ##
# [ 46, 48) 16   7.11%  20.44% ###
# [ 48, 50) 19   8.44%  28.89% ####
# [ 50, 51)  0   0.00%  28.89%
# [ 51, 53)  8   3.56%  32.44% ##
# [ 53, 55) 18   8.00%  40.44% ####
# [ 55, 57) 20   8.89%  49.33% ####
# [ 57, 58) 24  10.67%  60.00% #####
# [ 58, 60) 16   7.11%  67.11% ###
# [ 60, 62) 25  11.11%  78.22% #####
# [ 62, 63] 49  21.78% 100.00% ##########
#
# Depth by leafs:
# Count: 6270 Average: 4.9 StdDev: 0.414317
# Min: 2 Max: 5 Ignored: 0
# ----------------------------------------------
# [ 2, 3)   47   0.75%   0.75%
# [ 3, 4)  115   1.83%   2.58%
# [ 4, 5)  256   4.08%   6.67%
# [ 5, 5] 5852  93.33% 100.00% ##########
#
# Number of training obs by leaf:
# Count: 6270 Average: 5061.85 StdDev: 16485.6
# Min: 5 Max: 139174 Ignored: 0
# ----------------------------------------------
# [      5,   6963) 5440  86.76%  86.76% ##########
# [   6963,  13922)  358   5.71%  92.47% #
# [  13922,  20880)  116   1.85%  94.32%
# [  20880,  27839)   59   0.94%  95.26%
# [  27839,  34797)   45   0.72%  95.98%
# [  34797,  41756)   34   0.54%  96.52%
# [  41756,  48714)   37   0.59%  97.11%
# [  48714,  55673)   20   0.32%  97.43%
# [  55673,  62631)   12   0.19%  97.62%
# [  62631,  69590)   14   0.22%  97.85%
# [  69590,  76548)   22   0.35%  98.20%
# [  76548,  83507)   17   0.27%  98.47%
# [  83507,  90465)   11   0.18%  98.64%
# [  90465,  97424)   18   0.29%  98.93%
# [  97424, 104382)   10   0.16%  99.09%
# [ 104382, 111341)    8   0.13%  99.22%
# [ 111341, 118299)   16   0.26%  99.47%
# [ 118299, 125258)   11   0.18%  99.65%
# [ 125258, 132216)   13   0.21%  99.86%
# [ 132216, 139174]    9   0.14% 100.00%
#
# Attribute in nodes:
# 	837 : LongRunHighGrayLevelEmphasis [NUMERICAL]
# 	589 : RunEntropy [NUMERICAL]
# 	555 : GrayLevelNonUniformity [NUMERICAL]
# 	494 : GrayLevelVariance [NUMERICAL]
# 	431 : ShortRunLowGrayLevelEmphasis [NUMERICAL]
# 	412 : ShortRunHighGrayLevelEmphasis [NUMERICAL]
# 	381 : LongRunLowGrayLevelEmphasis [NUMERICAL]
# 	367 : RunVariance [NUMERICAL]
# 	364 : HighGrayLevelRunEmphasis [NUMERICAL]
# 	292 : LowGrayLevelRunEmphasis [NUMERICAL]
# 	279 : RunLengthNonUniformityNormalized [NUMERICAL]
# 	263 : ShortRunEmphasis [NUMERICAL]
# 	252 : GrayLevelNonUniformityNormalized [NUMERICAL]
# 	191 : LongRunEmphasis [NUMERICAL]
# 	173 : RunLengthNonUniformity [NUMERICAL]
# 	165 : RunPercentage [NUMERICAL]
#
# Attribute in nodes with depth <= 0:
# 	44 : GrayLevelNonUniformity [NUMERICAL]
# 	43 : LongRunHighGrayLevelEmphasis [NUMERICAL]
# 	26 : ShortRunLowGrayLevelEmphasis [NUMERICAL]
# 	25 : RunLengthNonUniformityNormalized [NUMERICAL]
# 	16 : LowGrayLevelRunEmphasis [NUMERICAL]
# 	15 : RunEntropy [NUMERICAL]
# 	12 : RunVariance [NUMERICAL]
# 	11 : RunLengthNonUniformity [NUMERICAL]
# 	8 : ShortRunHighGrayLevelEmphasis [NUMERICAL]
# 	8 : LongRunLowGrayLevelEmphasis [NUMERICAL]
# 	7 : ShortRunEmphasis [NUMERICAL]
# 	4 : HighGrayLevelRunEmphasis [NUMERICAL]
# 	3 : RunPercentage [NUMERICAL]
# 	2 : GrayLevelNonUniformityNormalized [NUMERICAL]
# 	1 : GrayLevelVariance [NUMERICAL]
#
# Attribute in nodes with depth <= 1:
# 	112 : LongRunHighGrayLevelEmphasis [NUMERICAL]
# 	76 : GrayLevelNonUniformity [NUMERICAL]
# 	60 : RunLengthNonUniformityNormalized [NUMERICAL]
# 	56 : RunVariance [NUMERICAL]
# 	56 : RunEntropy [NUMERICAL]
# 	45 : ShortRunLowGrayLevelEmphasis [NUMERICAL]
# 	38 : ShortRunHighGrayLevelEmphasis [NUMERICAL]
# 	38 : ShortRunEmphasis [NUMERICAL]
# 	35 : LowGrayLevelRunEmphasis [NUMERICAL]
# 	35 : GrayLevelVariance [NUMERICAL]
# 	28 : LongRunLowGrayLevelEmphasis [NUMERICAL]
# 	24 : LongRunEmphasis [NUMERICAL]
# 	22 : RunLengthNonUniformity [NUMERICAL]
# 	21 : GrayLevelNonUniformityNormalized [NUMERICAL]
# 	20 : HighGrayLevelRunEmphasis [NUMERICAL]
# 	9 : RunPercentage [NUMERICAL]
#
# Attribute in nodes with depth <= 2:
# 	227 : LongRunHighGrayLevelEmphasis [NUMERICAL]
# 	175 : GrayLevelNonUniformity [NUMERICAL]
# 	121 : RunEntropy [NUMERICAL]
# 	113 : RunVariance [NUMERICAL]
# 	103 : ShortRunLowGrayLevelEmphasis [NUMERICAL]
# 	102 : GrayLevelVariance [NUMERICAL]
# 	101 : ShortRunHighGrayLevelEmphasis [NUMERICAL]
# 	96 : RunLengthNonUniformityNormalized [NUMERICAL]
# 	86 : HighGrayLevelRunEmphasis [NUMERICAL]
# 	79 : ShortRunEmphasis [NUMERICAL]
# 	71 : LongRunLowGrayLevelEmphasis [NUMERICAL]
# 	69 : LowGrayLevelRunEmphasis [NUMERICAL]
# 	61 : GrayLevelNonUniformityNormalized [NUMERICAL]
# 	55 : LongRunEmphasis [NUMERICAL]
# 	38 : RunLengthNonUniformity [NUMERICAL]
# 	31 : RunPercentage [NUMERICAL]
#
# Attribute in nodes with depth <= 3:
# 	435 : LongRunHighGrayLevelEmphasis [NUMERICAL]
# 	304 : RunEntropy [NUMERICAL]
# 	299 : GrayLevelNonUniformity [NUMERICAL]
# 	236 : GrayLevelVariance [NUMERICAL]
# 	212 : ShortRunLowGrayLevelEmphasis [NUMERICAL]
# 	212 : ShortRunHighGrayLevelEmphasis [NUMERICAL]
# 	199 : RunVariance [NUMERICAL]
# 	184 : HighGrayLevelRunEmphasis [NUMERICAL]
# 	177 : LongRunLowGrayLevelEmphasis [NUMERICAL]
# 	174 : RunLengthNonUniformityNormalized [NUMERICAL]
# 	155 : LowGrayLevelRunEmphasis [NUMERICAL]
# 	153 : ShortRunEmphasis [NUMERICAL]
# 	125 : GrayLevelNonUniformityNormalized [NUMERICAL]
# 	98 : LongRunEmphasis [NUMERICAL]
# 	83 : RunLengthNonUniformity [NUMERICAL]
# 	73 : RunPercentage [NUMERICAL]
#
# Attribute in nodes with depth <= 5:
# 	837 : LongRunHighGrayLevelEmphasis [NUMERICAL]
# 	589 : RunEntropy [NUMERICAL]
# 	555 : GrayLevelNonUniformity [NUMERICAL]
# 	494 : GrayLevelVariance [NUMERICAL]
# 	431 : ShortRunLowGrayLevelEmphasis [NUMERICAL]
# 	412 : ShortRunHighGrayLevelEmphasis [NUMERICAL]
# 	381 : LongRunLowGrayLevelEmphasis [NUMERICAL]
# 	367 : RunVariance [NUMERICAL]
# 	364 : HighGrayLevelRunEmphasis [NUMERICAL]
# 	292 : LowGrayLevelRunEmphasis [NUMERICAL]
# 	279 : RunLengthNonUniformityNormalized [NUMERICAL]
# 	263 : ShortRunEmphasis [NUMERICAL]
# 	252 : GrayLevelNonUniformityNormalized [NUMERICAL]
# 	191 : LongRunEmphasis [NUMERICAL]
# 	173 : RunLengthNonUniformity [NUMERICAL]
# 	165 : RunPercentage [NUMERICAL]
#
# Condition type in nodes:
# 	6045 : HigherCondition
# Condition type in nodes with depth <= 0:
# 	225 : HigherCondition
# Condition type in nodes with depth <= 1:
# 	675 : HigherCondition
# Condition type in nodes with depth <= 2:
# 	1528 : HigherCondition
# Condition type in nodes with depth <= 3:
# 	3119 : HigherCondition
# Condition type in nodes with depth <= 5:
# 	6045 : HigherCondition
#
# Training logs:
# Number of iteration to final model: 225
# 	Iter:1 train-loss:1.287380 valid-loss:1.289663  train-accuracy:0.825806 valid-accuracy:0.819090
# 	Iter:2 train-loss:1.205812 valid-loss:1.210380  train-accuracy:0.837276 valid-accuracy:0.824710
# 	Iter:3 train-loss:1.137848 valid-loss:1.144052  train-accuracy:0.834269 valid-accuracy:0.821883
# 	Iter:4 train-loss:1.079698 valid-loss:1.087244  train-accuracy:0.840753 valid-accuracy:0.830785
# 	Iter:5 train-loss:1.030781 valid-loss:1.040324  train-accuracy:0.840361 valid-accuracy:0.830993
# 	Iter:6 train-loss:0.988437 valid-loss:0.999837  train-accuracy:0.841243 valid-accuracy:0.833327
# 	Iter:16 train-loss:0.755116 valid-loss:0.780273  train-accuracy:0.856067 valid-accuracy:0.841291
# 	Iter:26 train-loss:0.666758 valid-loss:0.698798  train-accuracy:0.865228 valid-accuracy:0.851170
# 	Iter:36 train-loss:0.623898 valid-loss:0.666137  train-accuracy:0.870771 valid-accuracy:0.858053
# 	Iter:46 train-loss:0.595917 valid-loss:0.645721  train-accuracy:0.875309 valid-accuracy:0.859186
# 	Iter:56 train-loss:0.573731 valid-loss:0.632399  train-accuracy:0.880051 valid-accuracy:0.862919
# 	Iter:66 train-loss:0.558943 valid-loss:0.624768  train-accuracy:0.884017 valid-accuracy:0.865333
# 	Iter:76 train-loss:0.545257 valid-loss:0.617967  train-accuracy:0.886838 valid-accuracy:0.864464
# 	Iter:86 train-loss:0.534582 valid-loss:0.614432  train-accuracy:0.888778 valid-accuracy:0.867048
# 	Iter:96 train-loss:0.524013 valid-loss:0.609560  train-accuracy:0.891945 valid-accuracy:0.869308
# 	Iter:106 train-loss:0.515087 valid-loss:0.606335  train-accuracy:0.893798 valid-accuracy:0.870302
# 	Iter:116 train-loss:0.506100 valid-loss:0.602811  train-accuracy:0.895919 valid-accuracy:0.869568
# 	Iter:126 train-loss:0.498764 valid-loss:0.601797  train-accuracy:0.898223 valid-accuracy:0.869518
# 	Iter:136 train-loss:0.491261 valid-loss:0.599303  train-accuracy:0.900371 valid-accuracy:0.869554
# 	Iter:146 train-loss:0.485437 valid-loss:0.596755  train-accuracy:0.901872 valid-accuracy:0.869862
# 	Iter:156 train-loss:0.478885 valid-loss:0.594838  train-accuracy:0.903200 valid-accuracy:0.869316
# 	Iter:166 train-loss:0.473625 valid-loss:0.594711  train-accuracy:0.904823 valid-accuracy:0.870360
# 	Iter:176 train-loss:0.467841 valid-loss:0.593680  train-accuracy:0.906711 valid-accuracy:0.870771
# 	Iter:186 train-loss:0.462576 valid-loss:0.592329  train-accuracy:0.908280 valid-accuracy:0.871388
# 	Iter:196 train-loss:0.457570 valid-loss:0.592103  train-accuracy:0.909597 valid-accuracy:0.871475
# 	Iter:206 train-loss:0.452907 valid-loss:0.591625  train-accuracy:0.911145 valid-accuracy:0.870997
# 	Iter:216 train-loss:0.448944 valid-loss:0.591632  train-accuracy:0.911970 valid-accuracy:0.870074
# 	Iter:226 train-loss:0.443559 valid-loss:0.591191  train-accuracy:0.913850 valid-accuracy:0.870211
# 	Iter:236 train-loss:0.439809 valid-loss:0.591332  train-accuracy:0.914806 valid-accuracy:0.870553
# 	Iter:246 train-loss:0.435159 valid-loss:0.591608  train-accuracy:0.916140 valid-accuracy:0.871598

# %%
# Model features
model.make_inspector().features()
# Out:
# ["GrayLevelNonUniformity" (1; #0),
#  "GrayLevelNonUniformityNormalized" (1; #1),
#  "GrayLevelVariance" (1; #2),
#  "HighGrayLevelRunEmphasis" (1; #3),
#  "LongRunEmphasis" (1; #4),
#  "LongRunHighGrayLevelEmphasis" (1; #5),
#  "LongRunLowGrayLevelEmphasis" (1; #6),
#  "LowGrayLevelRunEmphasis" (1; #7),
#  "RunEntropy" (1; #8),
#  "RunLengthNonUniformity" (1; #9),
#  "RunLengthNonUniformityNormalized" (1; #10),
#  "RunPercentage" (1; #11),
#  "RunVariance" (1; #12),
#  "ShortRunEmphasis" (1; #13),
#  "ShortRunHighGrayLevelEmphasis" (1; #14),
#  "ShortRunLowGrayLevelEmphasis" (1; #15)]

# %%
# Feature importance
model.make_inspector().variable_importances()
# Out:
# {'INV_MEAN_MIN_DEPTH': [("LongRunHighGrayLevelEmphasis" (1; #5),
#    0.24797033538320107),
#   ("GrayLevelNonUniformity" (1; #0), 0.22916957450456907),
#   ("RunEntropy" (1; #8), 0.20757859412688867),
#   ("ShortRunLowGrayLevelEmphasis" (1; #15), 0.20687256874790902),
#   ("RunLengthNonUniformityNormalized" (1; #10), 0.20430748991343856),
#   ("RunVariance" (1; #12), 0.19919544775878062),
#   ("ShortRunHighGrayLevelEmphasis" (1; #14), 0.19361829009659481),
#   ("LowGrayLevelRunEmphasis" (1; #7), 0.19285129149488833),
#   ("GrayLevelVariance" (1; #2), 0.1920748200539659),
#   ("LongRunLowGrayLevelEmphasis" (1; #6), 0.1894916557277553),
#   ("ShortRunEmphasis" (1; #13), 0.1887991436423414),
#   ("HighGrayLevelRunEmphasis" (1; #3), 0.1874279536099207),
#   ("RunLengthNonUniformity" (1; #9), 0.18290044024938976),
#   ("GrayLevelNonUniformityNormalized" (1; #1), 0.18266592627703665),
#   ("LongRunEmphasis" (1; #4), 0.18014231803129374),
#   ("RunPercentage" (1; #11), 0.17730091058966935)],
#  'SUM_SCORE': [("ShortRunLowGrayLevelEmphasis" (1; #15), 27796.595900900367),
#   ("LongRunHighGrayLevelEmphasis" (1; #5), 27378.306103590032),
#   ("ShortRunHighGrayLevelEmphasis" (1; #14), 17297.528537130336),
#   ("LowGrayLevelRunEmphasis" (1; #7), 16204.198544701501),
#   ("RunEntropy" (1; #8), 14151.556393968394),
#   ("GrayLevelNonUniformity" (1; #0), 9188.821410057799),
#   ("RunVariance" (1; #12), 6841.406700001793),
#   ("GrayLevelVariance" (1; #2), 3899.384515981107),
#   ("HighGrayLevelRunEmphasis" (1; #3), 3848.846776668344),
#   ("LongRunLowGrayLevelEmphasis" (1; #6), 2631.8732854171326),
#   ("ShortRunEmphasis" (1; #13), 2218.6106390876653),
#   ("RunLengthNonUniformityNormalized" (1; #10), 1980.0819570943486),
#   ("RunLengthNonUniformity" (1; #9), 1162.4248759689287),
#   ("GrayLevelNonUniformityNormalized" (1; #1), 1031.5185811194447),
#   ("LongRunEmphasis" (1; #4), 744.2494543810807),
#   ("RunPercentage" (1; #11), 685.3652783274152)],
#  'NUM_AS_ROOT': [("GrayLevelNonUniformity" (1; #0), 44.0),
#   ("LongRunHighGrayLevelEmphasis" (1; #5), 43.0),
#   ("ShortRunLowGrayLevelEmphasis" (1; #15), 26.0),
#   ("RunLengthNonUniformityNormalized" (1; #10), 25.0),
#   ("LowGrayLevelRunEmphasis" (1; #7), 16.0),
#   ("RunEntropy" (1; #8), 15.0),
#   ("RunVariance" (1; #12), 12.0),
#   ("RunLengthNonUniformity" (1; #9), 11.0),
#   ("LongRunLowGrayLevelEmphasis" (1; #6), 8.0),
#   ("ShortRunHighGrayLevelEmphasis" (1; #14), 8.0),
#   ("ShortRunEmphasis" (1; #13), 7.0),
#   ("HighGrayLevelRunEmphasis" (1; #3), 4.0),
#   ("RunPercentage" (1; #11), 3.0),
#   ("GrayLevelNonUniformityNormalized" (1; #1), 2.0),
#   ("GrayLevelVariance" (1; #2), 1.0)],
#  'NUM_NODES': [("LongRunHighGrayLevelEmphasis" (1; #5), 837.0),
#   ("RunEntropy" (1; #8), 589.0),
#   ("GrayLevelNonUniformity" (1; #0), 555.0),
#   ("GrayLevelVariance" (1; #2), 494.0),
#   ("ShortRunLowGrayLevelEmphasis" (1; #15), 431.0),
#   ("ShortRunHighGrayLevelEmphasis" (1; #14), 412.0),
#   ("LongRunLowGrayLevelEmphasis" (1; #6), 381.0),
#   ("RunVariance" (1; #12), 367.0),
#   ("HighGrayLevelRunEmphasis" (1; #3), 364.0),
#   ("LowGrayLevelRunEmphasis" (1; #7), 292.0),
#   ("RunLengthNonUniformityNormalized" (1; #10), 279.0),
#   ("ShortRunEmphasis" (1; #13), 263.0),
#   ("GrayLevelNonUniformityNormalized" (1; #1), 252.0),
#   ("LongRunEmphasis" (1; #4), 191.0),
#   ("RunLengthNonUniformity" (1; #9), 173.0),
#   ("RunPercentage" (1; #11), 165.0)]}

# %%
# Model self evaluation
model.make_inspector().evaluation()
# Out:
# Evaluation(num_examples=None, accuracy=0.8702450394630432, loss=0.591106653213501, rmse=None, ndcg=None, aucs=None, auuc=None, qini=None)

# %%
logs = model.make_inspector().training_logs()

plt.figure(figsize=(12, 4))
plt.subplot(1, 2, 1)
plt.plot([log.num_trees for log in logs], [log.evaluation.accuracy for log in logs])
plt.xlabel("Number of trees")
plt.ylabel("Accuracy (out-of-bag)")
plt.subplot(1, 2, 2)
plt.plot([log.num_trees for log in logs], [log.evaluation.loss for log in logs])
plt.xlabel("Number of trees")
plt.ylabel("Logloss (out-of-bag)")
plt.show()

# %% [markdown]
# Calculate the score of our hold-out validation dataset

# %%
predictions = model.predict(val_ds)
y_true      = validation_data["label"]

from sklearn.metrics import roc_auc_score
ROC_AUC = roc_auc_score(y_true, predictions)
print("The ROC AUC score is %.5f" % ROC_AUC )
# Out:
#  1/23 [>.............................] - ETA: 1s
# 23/23 [==============================] - 0s 4ms/step
# The ROC AUC score is 0.94737

# %%
# Compute binary classification metrics with sklearn
import numpy as np
from sklearn.metrics import (
    accuracy_score,
    precision_score,
    recall_score,
    f1_score,
    roc_auc_score,
    average_precision_score,
    confusion_matrix,
    classification_report,
    matthews_corrcoef,
    log_loss,
    brier_score_loss,
)

# Get predictions (probabilities or class labels)
preds = model.predict(test_ds)
# If model outputs probabilities, convert to labels by threshold 0.5
if preds.ndim == 2:
    # For TFDF classification, preds may be class probabilities with shape (N, 2)
    if preds.shape[1] == 2:
        pos_probs = preds[:, 1]
    else:
        # If single-probability column (positive class)
        pos_probs = preds[:, -1]
    y_pred = (pos_probs >= 0.5).astype(int)
else:
    # Already class labels
    y_pred = preds.astype(int)
    pos_probs = None

# Ground truth labels (must be 0/1 integers)
y_true = test_data["label"].astype(int).to_numpy()

# Core metrics
metrics = {}
metrics["accuracy"] = accuracy_score(y_true, y_pred)
metrics["precision"] = precision_score(y_true, y_pred, zero_division=0)
metrics["recall"] = recall_score(y_true, y_pred, zero_division=0)
metrics["f1"] = f1_score(y_true, y_pred, zero_division=0)
metrics["mcc"] = matthews_corrcoef(y_true, y_pred)

# Probabilistic metrics (only if we have probabilities)
if pos_probs is not None:
    metrics["roc_auc"] = roc_auc_score(y_true, pos_probs)
    metrics["pr_auc"] = average_precision_score(y_true, pos_probs)
    metrics["log_loss"] = log_loss(y_true, pos_probs, labels=[0,1])
    metrics["brier_score"] = brier_score_loss(y_true, pos_probs)

# Confusion matrix and detailed report
cm = confusion_matrix(y_true, y_pred, labels=[0,1])
report = classification_report(y_true, y_pred, digits=4)

print("Sklearn binary metrics:")
for k, v in metrics.items():
    print(f"{k}: {v:.4f}")
print("\nConfusion matrix:\n", cm)
print("\nClassification report:\n", report)
# Out:
# 45/45 [==============================] - 0s 5ms/step
# Sklearn binary metrics:
# accuracy: 0.8955
# precision: 0.3619
# recall: 0.8371
# f1: 0.5053
# mcc: 0.5075
# roc_auc: 0.9465
# pr_auc: 0.6849
# log_loss: 0.2524
# brier_score: 0.0763
#
# Confusion matrix:
#  [[37699  4214]
#  [  465  2390]]
#
# Classification report:
#                precision    recall  f1-score   support
#
#            0     0.9878    0.8995    0.9416     41913
#            1     0.3619    0.8371    0.5053      2855
#
#     accuracy                         0.8955     44768
#    macro avg     0.6749    0.8683    0.7235     44768
# weighted avg     0.9479    0.8955    0.9137     44768
