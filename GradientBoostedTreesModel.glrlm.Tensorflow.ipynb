# %%
# Import packages and modules
import numpy  as np
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow_decision_forests as tfdf

from sklearn.model_selection import train_test_split
# Out:
# 2026-05-18 17:50:38.580536: I tensorflow/core/util/port.cc:113] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2026-05-18 17:50:38.656735: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2026-05-18 17:50:40.408011: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
# Check the version of TensorFlow Decision Forests
print("Found TensorFlow Decision Forests v" + tfdf.__version__)
# Out:
# Found TensorFlow Decision Forests v1.9.1

# %%
# train/validation/test = 70/10/20
dataset = pd.read_csv('dataset/glrlm/kernel5-radius5/dataset.csv')

train_data, temp_data = train_test_split(
    dataset, test_size=0.3, random_state=42
 )
validation_data, test_data = train_test_split(
    temp_data, test_size=2/3, random_state=42
 )

# %%
# Convert the dataset into a TensorFlow dataset.
train_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    train_data, label="label"
)         
val_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    validation_data, label="label"
)
test_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    test_data, label="label"
)
# Out:
# 2026-05-18 17:50:43.531943: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:984] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2026-05-18 17:50:43.532367: W tensorflow/core/common_runtime/gpu/gpu_device.cc:2251] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...

# %%
import keras

# %%
# %%time

# Train a Gradient Boosted Trees model.
model = tfdf.keras.GradientBoostedTreesModel()

# Add evaluation metrics
model.compile(
    metrics=["accuracy"]
)
model.fit(x=train_ds)

# # Train a Gradient Boosted Trees model.
# model = tfdf.keras.GradientBoostedTreesModel(num_trees=1500)
# model.fit(train_ds)
# Out:
# Use /tmp/tmp35i7glms as temporary training directory
# Reading training dataset...
# [WARNING 26-05-18 17:50:43.7896 UTC gradient_boosted_trees.cc:1840] "goss_alpha" set but "sampling_method" not equal to "GOSS".
# [WARNING 26-05-18 17:50:43.7898 UTC gradient_boosted_trees.cc:1851] "goss_beta" set but "sampling_method" not equal to "GOSS".
# [WARNING 26-05-18 17:50:43.7899 UTC gradient_boosted_trees.cc:1865] "selective_gradient_boosting_ratio" set but "sampling_method" not equal to "SELGB".
# Training dataset read in 0:00:05.918612. Found 78035 examples.
# Training model...
# Model trained in 0:00:54.733513
# Compiling model...
# [INFO 26-05-18 17:51:44.4806 UTC kernel.cc:1233] Loading model from path /tmp/tmp35i7glms/model/ with prefix 6546c081c75b45a3
# [INFO 26-05-18 17:51:44.5061 UTC quick_scorer_extended.cc:911] The binary was compiled without AVX2 support, but your CPU supports it. Enable it for faster model inference.
# [INFO 26-05-18 17:51:44.5084 UTC abstract_model.cc:1362] Engine "GradientBoostedTreesQuickScorerExtended" built
# [INFO 26-05-18 17:51:44.5084 UTC kernel.cc:1061] Use fast generic engine
# Model compiled.
# CPU times: user 2min 23s, sys: 3.48 s, total: 2min 27s
# Wall time: 1min 27s

# %%
# Evaluate the model
evaluate = model.evaluate(val_ds, return_dict=True)
print()

for name, value in evaluate.items():
    print(f"{name}: {value:.4f}")
# Out:
# 12/12 [==============================] - 4s 5ms/step - loss: 0.0000e+00 - accuracy: 0.9636
#
# loss: 0.0000
# accuracy: 0.9636

# %%
# Model Summary
model.summary()
# Out:
# Model: "gradient_boosted_trees_model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
# =================================================================
# Total params: 1 (1.00 Byte)
# Trainable params: 0 (0.00 Byte)
# Non-trainable params: 1 (1.00 Byte)
# _________________________________________________________________
# Type: "GRADIENT_BOOSTED_TREES"
# Task: CLASSIFICATION
# Label: "__LABEL"
#
# Input Features (16):
# 	GrayLevelNonUniformity
# 	GrayLevelNonUniformityNormalized
# 	GrayLevelVariance
# 	HighGrayLevelRunEmphasis
# 	LongRunEmphasis
# 	LongRunHighGrayLevelEmphasis
# 	LongRunLowGrayLevelEmphasis
# 	LowGrayLevelRunEmphasis
# 	RunEntropy
# 	RunLengthNonUniformity
# 	RunLengthNonUniformityNormalized
# 	RunPercentage
# 	RunVariance
# 	ShortRunEmphasis
# 	ShortRunHighGrayLevelEmphasis
# 	ShortRunLowGrayLevelEmphasis
#
# No weights
#
# Variable Importance: INV_MEAN_MIN_DEPTH:
#     1.     "LongRunHighGrayLevelEmphasis"  0.266676 ################
#     2.                "GrayLevelVariance"  0.216466 ######
#     3.           "GrayLevelNonUniformity"  0.205837 ####
#     4.                       "RunEntropy"  0.205321 ####
#     5. "RunLengthNonUniformityNormalized"  0.204768 ####
#     6.                 "ShortRunEmphasis"  0.200817 ####
#     7.                      "RunVariance"  0.200774 ####
#     8.     "ShortRunLowGrayLevelEmphasis"  0.197565 ###
#     9.      "LongRunLowGrayLevelEmphasis"  0.196765 ###
#    10. "GrayLevelNonUniformityNormalized"  0.195533 ###
#    11.    "ShortRunHighGrayLevelEmphasis"  0.195438 ###
#    12.          "LowGrayLevelRunEmphasis"  0.189636 #
#    13.         "HighGrayLevelRunEmphasis"  0.187846 #
#    14.           "RunLengthNonUniformity"  0.182315
#    15.                  "LongRunEmphasis"  0.178960
#    16.                    "RunPercentage"  0.178684
#
# Variable Importance: NUM_AS_ROOT:
#     1.     "LongRunHighGrayLevelEmphasis" 101.000000 ################
#     2. "RunLengthNonUniformityNormalized" 33.000000 #####
#     3.           "GrayLevelNonUniformity" 27.000000 ####
#     4.                "GrayLevelVariance" 27.000000 ####
#     5.                 "ShortRunEmphasis" 26.000000 ###
#     6.                      "RunVariance" 21.000000 ###
#     7. "GrayLevelNonUniformityNormalized" 14.000000 #
#     8.     "ShortRunLowGrayLevelEmphasis" 12.000000 #
#     9.         "HighGrayLevelRunEmphasis"  8.000000
#    10.          "LowGrayLevelRunEmphasis"  8.000000
#    11.                       "RunEntropy"  8.000000
#    12.      "LongRunLowGrayLevelEmphasis"  6.000000
#    13.           "RunLengthNonUniformity"  6.000000
#    14.                  "LongRunEmphasis"  2.000000
#
# Variable Importance: NUM_NODES:
#     1.     "LongRunHighGrayLevelEmphasis" 889.000000 ################
#     2.                "GrayLevelVariance" 730.000000 ############
#     3.                       "RunEntropy" 720.000000 ############
#     4.     "ShortRunLowGrayLevelEmphasis" 574.000000 #########
#     5.           "GrayLevelNonUniformity" 570.000000 #########
#     6.    "ShortRunHighGrayLevelEmphasis" 478.000000 #######
#     7.      "LongRunLowGrayLevelEmphasis" 461.000000 ######
#     8. "GrayLevelNonUniformityNormalized" 431.000000 ######
#     9.                      "RunVariance" 395.000000 #####
#    10.         "HighGrayLevelRunEmphasis" 344.000000 ####
#    11.          "LowGrayLevelRunEmphasis" 338.000000 ####
#    12. "RunLengthNonUniformityNormalized" 335.000000 ####
#    13.                 "ShortRunEmphasis" 308.000000 ###
#    14.                  "LongRunEmphasis" 177.000000 #
#    15.           "RunLengthNonUniformity" 156.000000
#    16.                    "RunPercentage" 129.000000
#
# Variable Importance: SUM_SCORE:
#     1.     "LongRunHighGrayLevelEmphasis" 8355.545713 ################
#     2.           "GrayLevelNonUniformity" 1344.866952 ##
#     3.                       "RunEntropy" 899.300616 #
#     4.     "ShortRunLowGrayLevelEmphasis" 593.629298 #
#     5.          "LowGrayLevelRunEmphasis" 564.027801
#     6.    "ShortRunHighGrayLevelEmphasis" 474.120099
#     7.                "GrayLevelVariance" 423.732168
#     8.      "LongRunLowGrayLevelEmphasis" 367.669501
#     9.                      "RunVariance" 367.194996
#    10.                 "ShortRunEmphasis" 322.307199
#    11. "GrayLevelNonUniformityNormalized" 322.214062
#    12. "RunLengthNonUniformityNormalized" 250.310469
#    13.         "HighGrayLevelRunEmphasis" 236.784466
#    14.                  "LongRunEmphasis" 88.446890
#    15.                    "RunPercentage" 76.709726
#    16.           "RunLengthNonUniformity" 69.986422
#
#
#
# Loss: BINOMIAL_LOG_LIKELIHOOD
# Validation loss value: 0.211285
# Number of trees per iteration: 1
# Node format: NOT_SET
# Number of trees: 299
# Total number of nodes: 14369
#
# Number of nodes by tree:
# Count: 299 Average: 48.0569 StdDev: 9.31824
# Min: 15 Max: 63 Ignored: 0
# ----------------------------------------------
# [ 15, 17)  1   0.33%   0.33%
# [ 17, 19)  2   0.67%   1.00%
# [ 19, 22)  0   0.00%   1.00%
# [ 22, 24)  0   0.00%   1.00%
# [ 24, 27)  0   0.00%   1.00%
# [ 27, 29)  0   0.00%   1.00%
# [ 29, 32) 12   4.01%   5.02% ###
# [ 32, 34)  9   3.01%   8.03% ##
# [ 34, 37) 11   3.68%  11.71% ###
# [ 37, 39)  8   2.68%  14.38% ##
# [ 39, 41) 11   3.68%  18.06% ###
# [ 41, 44) 43  14.38%  32.44% ##########
# [ 44, 46) 21   7.02%  39.46% #####
# [ 46, 49) 35  11.71%  51.17% ########
# [ 49, 51) 22   7.36%  58.53% #####
# [ 51, 54) 34  11.37%  69.90% ########
# [ 54, 56) 16   5.35%  75.25% ####
# [ 56, 59) 18   6.02%  81.27% ####
# [ 59, 61) 25   8.36%  89.63% ######
# [ 61, 63] 31  10.37% 100.00% #######
#
# Depth by leafs:
# Count: 7334 Average: 4.79316 StdDev: 0.572911
# Min: 2 Max: 5 Ignored: 0
# ----------------------------------------------
# [ 2, 3)  115   1.57%   1.57%
# [ 3, 4)  257   3.50%   5.07%
# [ 4, 5)  658   8.97%  14.04% #
# [ 5, 5] 6304  85.96% 100.00% ##########
#
# Number of training obs by leaf:
# Count: 7334 Average: 2862.92 StdDev: 10465.7
# Min: 5 Max: 70177 Ignored: 0
# ----------------------------------------------
# [     5,  3513) 6511  88.78%  88.78% ##########
# [  3513,  7022)  249   3.40%  92.17%
# [  7022, 10530)  120   1.64%  93.81%
# [ 10530, 14039)   92   1.25%  95.06%
# [ 14039, 17548)   37   0.50%  95.57%
# [ 17548, 21056)   38   0.52%  96.09%
# [ 21056, 24565)   19   0.26%  96.35%
# [ 24565, 28074)   17   0.23%  96.58%
# [ 28074, 31582)   23   0.31%  96.89%
# [ 31582, 35091)    6   0.08%  96.97%
# [ 35091, 38600)    4   0.05%  97.03%
# [ 38600, 42108)    8   0.11%  97.14%
# [ 42108, 45617)   16   0.22%  97.35%
# [ 45617, 49126)   23   0.31%  97.67%
# [ 49126, 52634)   19   0.26%  97.93%
# [ 52634, 56143)   27   0.37%  98.30%
# [ 56143, 59652)   18   0.25%  98.54%
# [ 59652, 63160)   27   0.37%  98.91%
# [ 63160, 66669)   30   0.41%  99.32%
# [ 66669, 70177]   50   0.68% 100.00%
#
# Attribute in nodes:
# 	889 : LongRunHighGrayLevelEmphasis [NUMERICAL]
# 	730 : GrayLevelVariance [NUMERICAL]
# 	720 : RunEntropy [NUMERICAL]
# 	574 : ShortRunLowGrayLevelEmphasis [NUMERICAL]
# 	570 : GrayLevelNonUniformity [NUMERICAL]
# 	478 : ShortRunHighGrayLevelEmphasis [NUMERICAL]
# 	461 : LongRunLowGrayLevelEmphasis [NUMERICAL]
# 	431 : GrayLevelNonUniformityNormalized [NUMERICAL]
# 	395 : RunVariance [NUMERICAL]
# 	344 : HighGrayLevelRunEmphasis [NUMERICAL]
# 	338 : LowGrayLevelRunEmphasis [NUMERICAL]
# 	335 : RunLengthNonUniformityNormalized [NUMERICAL]
# 	308 : ShortRunEmphasis [NUMERICAL]
# 	177 : LongRunEmphasis [NUMERICAL]
# 	156 : RunLengthNonUniformity [NUMERICAL]
# 	129 : RunPercentage [NUMERICAL]
#
# Attribute in nodes with depth <= 0:
# 	101 : LongRunHighGrayLevelEmphasis [NUMERICAL]
# 	33 : RunLengthNonUniformityNormalized [NUMERICAL]
# 	27 : GrayLevelVariance [NUMERICAL]
# 	27 : GrayLevelNonUniformity [NUMERICAL]
# 	26 : ShortRunEmphasis [NUMERICAL]
# 	21 : RunVariance [NUMERICAL]
# 	14 : GrayLevelNonUniformityNormalized [NUMERICAL]
# 	12 : ShortRunLowGrayLevelEmphasis [NUMERICAL]
# 	8 : RunEntropy [NUMERICAL]
# 	8 : LowGrayLevelRunEmphasis [NUMERICAL]
# 	8 : HighGrayLevelRunEmphasis [NUMERICAL]
# 	6 : RunLengthNonUniformity [NUMERICAL]
# 	6 : LongRunLowGrayLevelEmphasis [NUMERICAL]
# 	2 : LongRunEmphasis [NUMERICAL]
#
# Attribute in nodes with depth <= 1:
# 	181 : LongRunHighGrayLevelEmphasis [NUMERICAL]
# 	98 : GrayLevelVariance [NUMERICAL]
# 	73 : RunLengthNonUniformityNormalized [NUMERICAL]
# 	64 : RunEntropy [NUMERICAL]
# 	58 : ShortRunEmphasis [NUMERICAL]
# 	58 : RunVariance [NUMERICAL]
# 	57 : GrayLevelNonUniformityNormalized [NUMERICAL]
# 	57 : GrayLevelNonUniformity [NUMERICAL]
# 	51 : ShortRunHighGrayLevelEmphasis [NUMERICAL]
# 	51 : LongRunLowGrayLevelEmphasis [NUMERICAL]
# 	41 : ShortRunLowGrayLevelEmphasis [NUMERICAL]
# 	36 : LowGrayLevelRunEmphasis [NUMERICAL]
# 	28 : HighGrayLevelRunEmphasis [NUMERICAL]
# 	23 : RunLengthNonUniformity [NUMERICAL]
# 	12 : RunPercentage [NUMERICAL]
# 	9 : LongRunEmphasis [NUMERICAL]
#
# Attribute in nodes with depth <= 2:
# 	285 : LongRunHighGrayLevelEmphasis [NUMERICAL]
# 	216 : GrayLevelVariance [NUMERICAL]
# 	179 : RunEntropy [NUMERICAL]
# 	141 : LongRunLowGrayLevelEmphasis [NUMERICAL]
# 	139 : GrayLevelNonUniformity [NUMERICAL]
# 	136 : RunVariance [NUMERICAL]
# 	131 : RunLengthNonUniformityNormalized [NUMERICAL]
# 	130 : GrayLevelNonUniformityNormalized [NUMERICAL]
# 	128 : ShortRunHighGrayLevelEmphasis [NUMERICAL]
# 	123 : ShortRunLowGrayLevelEmphasis [NUMERICAL]
# 	109 : ShortRunEmphasis [NUMERICAL]
# 	86 : LowGrayLevelRunEmphasis [NUMERICAL]
# 	75 : HighGrayLevelRunEmphasis [NUMERICAL]
# 	40 : RunLengthNonUniformity [NUMERICAL]
# 	33 : RunPercentage [NUMERICAL]
# 	27 : LongRunEmphasis [NUMERICAL]
#
# Attribute in nodes with depth <= 3:
# 	523 : LongRunHighGrayLevelEmphasis [NUMERICAL]
# 	404 : GrayLevelVariance [NUMERICAL]
# 	379 : RunEntropy [NUMERICAL]
# 	304 : GrayLevelNonUniformity [NUMERICAL]
# 	303 : ShortRunLowGrayLevelEmphasis [NUMERICAL]
# 	270 : LongRunLowGrayLevelEmphasis [NUMERICAL]
# 	253 : GrayLevelNonUniformityNormalized [NUMERICAL]
# 	248 : ShortRunHighGrayLevelEmphasis [NUMERICAL]
# 	217 : RunVariance [NUMERICAL]
# 	216 : RunLengthNonUniformityNormalized [NUMERICAL]
# 	189 : LowGrayLevelRunEmphasis [NUMERICAL]
# 	173 : ShortRunEmphasis [NUMERICAL]
# 	172 : HighGrayLevelRunEmphasis [NUMERICAL]
# 	84 : RunLengthNonUniformity [NUMERICAL]
# 	84 : LongRunEmphasis [NUMERICAL]
# 	64 : RunPercentage [NUMERICAL]
#
# Attribute in nodes with depth <= 5:
# 	889 : LongRunHighGrayLevelEmphasis [NUMERICAL]
# 	730 : GrayLevelVariance [NUMERICAL]
# 	720 : RunEntropy [NUMERICAL]
# 	574 : ShortRunLowGrayLevelEmphasis [NUMERICAL]
# 	570 : GrayLevelNonUniformity [NUMERICAL]
# 	478 : ShortRunHighGrayLevelEmphasis [NUMERICAL]
# 	461 : LongRunLowGrayLevelEmphasis [NUMERICAL]
# 	431 : GrayLevelNonUniformityNormalized [NUMERICAL]
# 	395 : RunVariance [NUMERICAL]
# 	344 : HighGrayLevelRunEmphasis [NUMERICAL]
# 	338 : LowGrayLevelRunEmphasis [NUMERICAL]
# 	335 : RunLengthNonUniformityNormalized [NUMERICAL]
# 	308 : ShortRunEmphasis [NUMERICAL]
# 	177 : LongRunEmphasis [NUMERICAL]
# 	156 : RunLengthNonUniformity [NUMERICAL]
# 	129 : RunPercentage [NUMERICAL]
#
# Condition type in nodes:
# 	7035 : HigherCondition
# Condition type in nodes with depth <= 0:
# 	299 : HigherCondition
# Condition type in nodes with depth <= 1:
# 	897 : HigherCondition
# Condition type in nodes with depth <= 2:
# 	1978 : HigherCondition
# Condition type in nodes with depth <= 3:
# 	3883 : HigherCondition
# Condition type in nodes with depth <= 5:
# 	7035 : HigherCondition
#
# Training logs:
# Number of iteration to final model: 299
# 	Iter:1 train-loss:0.441447 valid-loss:0.449775  train-accuracy:0.926990 valid-accuracy:0.925243
# 	Iter:2 train-loss:0.410815 valid-loss:0.418902  train-accuracy:0.926990 valid-accuracy:0.925243
# 	Iter:3 train-loss:0.388120 valid-loss:0.396024  train-accuracy:0.927004 valid-accuracy:0.925243
# 	Iter:4 train-loss:0.370547 valid-loss:0.378431  train-accuracy:0.927047 valid-accuracy:0.925243
# 	Iter:5 train-loss:0.356743 valid-loss:0.364773  train-accuracy:0.941259 valid-accuracy:0.941500
# 	Iter:6 train-loss:0.345066 valid-loss:0.353552  train-accuracy:0.947766 valid-accuracy:0.947645
# 	Iter:16 train-loss:0.276558 valid-loss:0.288161  train-accuracy:0.958917 valid-accuracy:0.955325
# 	Iter:26 train-loss:0.250470 valid-loss:0.264504  train-accuracy:0.960554 valid-accuracy:0.956605
# 	Iter:36 train-loss:0.234536 valid-loss:0.251260  train-accuracy:0.961978 valid-accuracy:0.957373
# 	Iter:46 train-loss:0.222010 valid-loss:0.241695  train-accuracy:0.963602 valid-accuracy:0.959293
# 	Iter:56 train-loss:0.212738 valid-loss:0.234844  train-accuracy:0.964542 valid-accuracy:0.960317
# 	Iter:66 train-loss:0.205942 valid-loss:0.230987  train-accuracy:0.965439 valid-accuracy:0.960829
# 	Iter:76 train-loss:0.201191 valid-loss:0.228080  train-accuracy:0.966279 valid-accuracy:0.961342
# 	Iter:86 train-loss:0.196937 valid-loss:0.226264  train-accuracy:0.966962 valid-accuracy:0.961726
# 	Iter:96 train-loss:0.191894 valid-loss:0.224154  train-accuracy:0.967589 valid-accuracy:0.961470
# 	Iter:106 train-loss:0.188612 valid-loss:0.222650  train-accuracy:0.968216 valid-accuracy:0.962110
# 	Iter:116 train-loss:0.185140 valid-loss:0.221135  train-accuracy:0.968899 valid-accuracy:0.961982
# 	Iter:126 train-loss:0.181992 valid-loss:0.220173  train-accuracy:0.969341 valid-accuracy:0.962494
# 	Iter:136 train-loss:0.178234 valid-loss:0.218636  train-accuracy:0.969896 valid-accuracy:0.962238
# 	Iter:146 train-loss:0.175036 valid-loss:0.218078  train-accuracy:0.970437 valid-accuracy:0.961982
# 	Iter:156 train-loss:0.172351 valid-loss:0.217615  train-accuracy:0.970950 valid-accuracy:0.962110
# 	Iter:166 train-loss:0.169703 valid-loss:0.217020  train-accuracy:0.971306 valid-accuracy:0.962238
# 	Iter:176 train-loss:0.167613 valid-loss:0.215866  train-accuracy:0.971804 valid-accuracy:0.961982
# 	Iter:186 train-loss:0.164734 valid-loss:0.215367  train-accuracy:0.972103 valid-accuracy:0.962366
# 	Iter:196 train-loss:0.161523 valid-loss:0.214106  train-accuracy:0.972473 valid-accuracy:0.962366
# 	Iter:206 train-loss:0.159586 valid-loss:0.214021  train-accuracy:0.973086 valid-accuracy:0.962366
# 	Iter:216 train-loss:0.157111 valid-loss:0.213388  train-accuracy:0.973570 valid-accuracy:0.962750
# 	Iter:226 train-loss:0.155480 valid-loss:0.213219  train-accuracy:0.973840 valid-accuracy:0.963006
# 	Iter:236 train-loss:0.154179 valid-loss:0.213439  train-accuracy:0.974068 valid-accuracy:0.962878
# 	Iter:246 train-loss:0.151947 valid-loss:0.212606  train-accuracy:0.974410 valid-accuracy:0.962366
# 	Iter:256 train-loss:0.149794 valid-loss:0.212056  train-accuracy:0.974595 valid-accuracy:0.963006
# 	Iter:266 train-loss:0.148028 valid-loss:0.211753  train-accuracy:0.975037 valid-accuracy:0.963006
# 	Iter:276 train-loss:0.146846 valid-loss:0.211830  train-accuracy:0.975293 valid-accuracy:0.962750
# 	Iter:286 train-loss:0.144615 valid-loss:0.211549  train-accuracy:0.975549 valid-accuracy:0.962750
# 	Iter:296 train-loss:0.143065 valid-loss:0.211304  train-accuracy:0.975806 valid-accuracy:0.962878

# %%
# Model features
model.make_inspector().features()
# Out:
# ["GrayLevelNonUniformity" (1; #0),
#  "GrayLevelNonUniformityNormalized" (1; #1),
#  "GrayLevelVariance" (1; #2),
#  "HighGrayLevelRunEmphasis" (1; #3),
#  "LongRunEmphasis" (1; #4),
#  "LongRunHighGrayLevelEmphasis" (1; #5),
#  "LongRunLowGrayLevelEmphasis" (1; #6),
#  "LowGrayLevelRunEmphasis" (1; #7),
#  "RunEntropy" (1; #8),
#  "RunLengthNonUniformity" (1; #9),
#  "RunLengthNonUniformityNormalized" (1; #10),
#  "RunPercentage" (1; #11),
#  "RunVariance" (1; #12),
#  "ShortRunEmphasis" (1; #13),
#  "ShortRunHighGrayLevelEmphasis" (1; #14),
#  "ShortRunLowGrayLevelEmphasis" (1; #15)]

# %%
# Feature importance
model.make_inspector().variable_importances()
# Out:
# {'INV_MEAN_MIN_DEPTH': [("LongRunHighGrayLevelEmphasis" (1; #5),
#    0.2666761105636472),
#   ("GrayLevelVariance" (1; #2), 0.2164656528666016),
#   ("GrayLevelNonUniformity" (1; #0), 0.20583742348630535),
#   ("RunEntropy" (1; #8), 0.20532126768279216),
#   ("RunLengthNonUniformityNormalized" (1; #10), 0.204767917684075),
#   ("ShortRunEmphasis" (1; #13), 0.20081739680119534),
#   ("RunVariance" (1; #12), 0.20077395138385049),
#   ("ShortRunLowGrayLevelEmphasis" (1; #15), 0.19756521768327132),
#   ("LongRunLowGrayLevelEmphasis" (1; #6), 0.19676509847196136),
#   ("GrayLevelNonUniformityNormalized" (1; #1), 0.19553333709034224),
#   ("ShortRunHighGrayLevelEmphasis" (1; #14), 0.19543789913740273),
#   ("LowGrayLevelRunEmphasis" (1; #7), 0.18963629290253048),
#   ("HighGrayLevelRunEmphasis" (1; #3), 0.18784550003749248),
#   ("RunLengthNonUniformity" (1; #9), 0.1823154175129253),
#   ("LongRunEmphasis" (1; #4), 0.17895972607507032),
#   ("RunPercentage" (1; #11), 0.17868443157802846)],
#  'SUM_SCORE': [("LongRunHighGrayLevelEmphasis" (1; #5), 8355.5457131955),
#   ("GrayLevelNonUniformity" (1; #0), 1344.8669515781278),
#   ("RunEntropy" (1; #8), 899.300615775985),
#   ("ShortRunLowGrayLevelEmphasis" (1; #15), 593.6292982954905),
#   ("LowGrayLevelRunEmphasis" (1; #7), 564.0278006370919),
#   ("ShortRunHighGrayLevelEmphasis" (1; #14), 474.1200992046553),
#   ("GrayLevelVariance" (1; #2), 423.73216807688794),
#   ("LongRunLowGrayLevelEmphasis" (1; #6), 367.66950055913264),
#   ("RunVariance" (1; #12), 367.1949956519237),
#   ("ShortRunEmphasis" (1; #13), 322.3071985709603),
#   ("GrayLevelNonUniformityNormalized" (1; #1), 322.2140616463346),
#   ("RunLengthNonUniformityNormalized" (1; #10), 250.31046895284598),
#   ("HighGrayLevelRunEmphasis" (1; #3), 236.78446584365292),
#   ("LongRunEmphasis" (1; #4), 88.44689023738323),
#   ("RunPercentage" (1; #11), 76.70972574317477),
#   ("RunLengthNonUniformity" (1; #9), 69.98642204995045)],
#  'NUM_AS_ROOT': [("LongRunHighGrayLevelEmphasis" (1; #5), 101.0),
#   ("RunLengthNonUniformityNormalized" (1; #10), 33.0),
#   ("GrayLevelNonUniformity" (1; #0), 27.0),
#   ("GrayLevelVariance" (1; #2), 27.0),
#   ("ShortRunEmphasis" (1; #13), 26.0),
#   ("RunVariance" (1; #12), 21.0),
#   ("GrayLevelNonUniformityNormalized" (1; #1), 14.0),
#   ("ShortRunLowGrayLevelEmphasis" (1; #15), 12.0),
#   ("HighGrayLevelRunEmphasis" (1; #3), 8.0),
#   ("LowGrayLevelRunEmphasis" (1; #7), 8.0),
#   ("RunEntropy" (1; #8), 8.0),
#   ("LongRunLowGrayLevelEmphasis" (1; #6), 6.0),
#   ("RunLengthNonUniformity" (1; #9), 6.0),
#   ("LongRunEmphasis" (1; #4), 2.0)],
#  'NUM_NODES': [("LongRunHighGrayLevelEmphasis" (1; #5), 889.0),
#   ("GrayLevelVariance" (1; #2), 730.0),
#   ("RunEntropy" (1; #8), 720.0),
#   ("ShortRunLowGrayLevelEmphasis" (1; #15), 574.0),
#   ("GrayLevelNonUniformity" (1; #0), 570.0),
#   ("ShortRunHighGrayLevelEmphasis" (1; #14), 478.0),
#   ("LongRunLowGrayLevelEmphasis" (1; #6), 461.0),
#   ("GrayLevelNonUniformityNormalized" (1; #1), 431.0),
#   ("RunVariance" (1; #12), 395.0),
#   ("HighGrayLevelRunEmphasis" (1; #3), 344.0),
#   ("LowGrayLevelRunEmphasis" (1; #7), 338.0),
#   ("RunLengthNonUniformityNormalized" (1; #10), 335.0),
#   ("ShortRunEmphasis" (1; #13), 308.0),
#   ("LongRunEmphasis" (1; #4), 177.0),
#   ("RunLengthNonUniformity" (1; #9), 156.0),
#   ("RunPercentage" (1; #11), 129.0)]}

# %%
# Model self evaluation
model.make_inspector().evaluation()
# Out:
# Evaluation(num_examples=None, accuracy=0.962877631187439, loss=0.21128538250923157, rmse=None, ndcg=None, aucs=None, auuc=None, qini=None)

# %%
logs = model.make_inspector().training_logs()

plt.figure(figsize=(12, 4))
plt.subplot(1, 2, 1)
plt.plot([log.num_trees for log in logs], [log.evaluation.accuracy for log in logs])
plt.xlabel("Number of trees")
plt.ylabel("Accuracy (out-of-bag)")
plt.subplot(1, 2, 2)
plt.plot([log.num_trees for log in logs], [log.evaluation.loss for log in logs])
plt.xlabel("Number of trees")
plt.ylabel("Logloss (out-of-bag)")
plt.show()

# %% [markdown]
# Calculate the score of our hold-out validation dataset

# %%
predictions = model.predict(val_ds)
y_true      = validation_data["label"]

from sklearn.metrics import roc_auc_score
ROC_AUC = roc_auc_score(y_true, predictions)
print("The ROC AUC score is %.5f" % ROC_AUC )
# Out:
# 12/12 [==============================] - 0s 4ms/step
# The ROC AUC score is 0.95700

# %%
# Compute binary classification metrics with sklearn
import numpy as np
from sklearn.metrics import (
    accuracy_score,
    precision_score,
    recall_score,
    f1_score,
    roc_auc_score,
    average_precision_score,
    confusion_matrix,
    classification_report,
    matthews_corrcoef,
    log_loss,
    brier_score_loss,
)

# Get predictions (probabilities or class labels)
preds = model.predict(test_ds)
# If model outputs probabilities, convert to labels by threshold 0.5
if preds.ndim == 2:
    # For TFDF classification, preds may be class probabilities with shape (N, 2)
    if preds.shape[1] == 2:
        pos_probs = preds[:, 1]
    else:
        # If single-probability column (positive class)
        pos_probs = preds[:, -1]
    y_pred = (pos_probs >= 0.5).astype(int)
else:
    # Already class labels
    y_pred = preds.astype(int)
    pos_probs = None

# Ground truth labels (must be 0/1 integers)
y_true = test_data["label"].astype(int).to_numpy()

# Core metrics
metrics = {}
metrics["accuracy"] = accuracy_score(y_true, y_pred)
metrics["precision"] = precision_score(y_true, y_pred, zero_division=0)
metrics["recall"] = recall_score(y_true, y_pred, zero_division=0)
metrics["f1"] = f1_score(y_true, y_pred, zero_division=0)
metrics["mcc"] = matthews_corrcoef(y_true, y_pred)

# Probabilistic metrics (only if we have probabilities)
if pos_probs is not None:
    metrics["roc_auc"] = roc_auc_score(y_true, pos_probs)
    metrics["pr_auc"] = average_precision_score(y_true, pos_probs)
    metrics["log_loss"] = log_loss(y_true, pos_probs, labels=[0,1])
    metrics["brier_score"] = brier_score_loss(y_true, pos_probs)

# Confusion matrix and detailed report
cm = confusion_matrix(y_true, y_pred, labels=[0,1])
report = classification_report(y_true, y_pred, digits=4)

print("Sklearn binary metrics:")
for k, v in metrics.items():
    print(f"{k}: {v:.4f}")
print("\nConfusion matrix:\n", cm)
print("\nClassification report:\n", report)
# Out:
# 23/23 [==============================] - 0s 5ms/step
# Sklearn binary metrics:
# accuracy: 0.9652
# precision: 0.8472
# recall: 0.6197
# f1: 0.7158
# mcc: 0.7075
# roc_auc: 0.9591
# pr_auc: 0.7975
# log_loss: 0.1037
# brier_score: 0.0277
#
# Confusion matrix:
#  [[20545   176]
#  [  599   976]]
#
# Classification report:
#                precision    recall  f1-score   support
#
#            0     0.9717    0.9915    0.9815     20721
#            1     0.8472    0.6197    0.7158      1575
#
#     accuracy                         0.9652     22296
#    macro avg     0.9094    0.8056    0.8486     22296
# weighted avg     0.9629    0.9652    0.9627     22296
