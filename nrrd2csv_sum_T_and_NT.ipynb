# %%
featureClass = 'ngtdm'

# %%
import os
import pandas as pd
from pathlib import Path

datasetPath = f"dataset/{featureClass}/kernel5-radius5/non_tumor"
batch: list[pd.DataFrame] = []
merged_count = 0

patientFolders = os.listdir(datasetPath)
patientFolders.sort()
for patientFolder in patientFolders:
  if patientFolder.startswith('BraTS2021_'):
    csvPath = f"{datasetPath}/{patientFolder}/nrrd2csv.csv"
    df = pd.read_csv(csvPath)
    df.insert(0, 'label', 0)
    batch.append(df)
    merged_count += 1

    if merged_count % 100 == 0:
      merged = pd.concat(batch, ignore_index=True)
      output_merged = f'{datasetPath}/{merged_count}.dataset.csv'
      Path(output_merged).parent.mkdir(parents=True, exist_ok=True)
      merged.to_csv(output_merged, index=False)

if batch:
  merged = pd.concat(batch, ignore_index=True)
  output_merged = f'{datasetPath}/{merged_count}.dataset.csv'
  Path(output_merged).parent.mkdir(parents=True, exist_ok=True)
  merged.to_csv(output_merged, index=False)

# %%
import os
import pandas as pd
from pathlib import Path

datasetPath = f"dataset/{featureClass}/kernel5-radius5/tumor"
batch: list[pd.DataFrame] = []
merged_count = 0

patientFolders = os.listdir(datasetPath)
patientFolders.sort()
for patientFolder in patientFolders:
  if patientFolder.startswith('BraTS2021_'):
    csvPath = f"{datasetPath}/{patientFolder}/nrrd2csv.csv"
    df = pd.read_csv(csvPath)
    df.insert(0, 'label', 1)
    batch.append(df)
    merged_count += 1

    if merged_count % 100 == 0:
      merged = pd.concat(batch, ignore_index=True)
      output_merged = f'{datasetPath}/{merged_count}.dataset.csv'
      Path(output_merged).parent.mkdir(parents=True, exist_ok=True)
      merged.to_csv(output_merged, index=False)

if batch:
  merged = pd.concat(batch, ignore_index=True)
  output_merged = f'{datasetPath}/{merged_count}.dataset.csv'
  Path(output_merged).parent.mkdir(parents=True, exist_ok=True)
  merged.to_csv(output_merged, index=False)

# %%
import pandas as pd
from pathlib import Path

datasetPath = f"dataset/{featureClass}/kernel5-radius5"

tumorDf = pd.read_csv(f'{datasetPath}/tumor/100.dataset.csv')
nonTumorDf = pd.read_csv(f'{datasetPath}/non_tumor/100.dataset.csv')

merged = pd.concat([tumorDf, nonTumorDf], ignore_index=True)
merged = merged.sample(frac=1)  # Shuffle the dataset
output_merged = f'{datasetPath}/100.dataset.csv'
Path(output_merged).parent.mkdir(parents=True, exist_ok=True)
merged.to_csv(output_merged, index=False)


tumorDf = pd.read_csv(f'{datasetPath}/tumor/200.dataset.csv')
nonTumorDf = pd.read_csv(f'{datasetPath}/non_tumor/200.dataset.csv')

merged = pd.concat([tumorDf, nonTumorDf], ignore_index=True)
merged = merged.sample(frac=1)  # Shuffle the dataset
output_merged = f'{datasetPath}/200.dataset.csv'
Path(output_merged).parent.mkdir(parents=True, exist_ok=True)
merged.to_csv(output_merged, index=False)


tumorDf = pd.read_csv(f'{datasetPath}/tumor/300.dataset.csv')
nonTumorDf = pd.read_csv(f'{datasetPath}/non_tumor/300.dataset.csv')

merged = pd.concat([tumorDf, nonTumorDf], ignore_index=True)
merged = merged.sample(frac=1)  # Shuffle the dataset
output_merged = f'{datasetPath}/300.dataset.csv'
Path(output_merged).parent.mkdir(parents=True, exist_ok=True)
merged.to_csv(output_merged, index=False)


tumorDf = pd.read_csv(f'{datasetPath}/tumor/400.dataset.csv')
nonTumorDf = pd.read_csv(f'{datasetPath}/non_tumor/400.dataset.csv')

merged = pd.concat([tumorDf, nonTumorDf], ignore_index=True)
merged = merged.sample(frac=1)  # Shuffle the dataset
output_merged = f'{datasetPath}/400.dataset.csv'
Path(output_merged).parent.mkdir(parents=True, exist_ok=True)
merged.to_csv(output_merged, index=False)


tumorDf = pd.read_csv(f'{datasetPath}/tumor/500.dataset.csv')
nonTumorDf = pd.read_csv(f'{datasetPath}/non_tumor/500.dataset.csv')

merged = pd.concat([tumorDf, nonTumorDf], ignore_index=True)
merged = merged.sample(frac=1)  # Shuffle the dataset
output_merged = f'{datasetPath}/500.dataset.csv'
Path(output_merged).parent.mkdir(parents=True, exist_ok=True)
merged.to_csv(output_merged, index=False)

# %%
# tumorDf = pd.read_csv(f'{datasetPath}/tumor/499.dataset.csv')
# nonTumorDf = pd.read_csv(f'{datasetPath}/non_tumor/499.dataset.csv')

# merged = pd.concat([tumorDf, nonTumorDf], ignore_index=True)
# merged = merged.sample(frac=1)  # Shuffle the dataset
# output_merged = f'{datasetPath}/500.dataset.csv'
# Path(output_merged).parent.mkdir(parents=True, exist_ok=True)
# merged.to_csv(output_merged, index=False)
