# %% [markdown]
# <a href="https://colab.research.google.com/github/ntatfff/todo/blob/202411241258/ColabRadiomicsFeatureExtractor.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import radiomics
import numpy as np
import SimpleITK as sitk
import radiomics.featureextractor
import os
import six
from os import path
import pandas as pd

def featureExtractor(fileId):
  imagePath = './dataset/BraTS2021_Training_Data/%s/%s_flair.nii.gz' % (fileId, fileId)
  image = sitk.ReadImage(imagePath)
  maskPath ='./dataset/BraTS2021_Training_Data/%s/%s_kernel5_non_tumor.nii.gz' % (fileId, fileId)
  mask = sitk.ReadImage(maskPath)

  kernel = 5
  settings = {}
  settings['kernelRadius'] = kernel
  settings['maskedKernel'] = False
  settings['voxelBatch'] = 200
  extractor = radiomics.featureextractor.RadiomicsFeatureExtractor(**settings)
  extractor.disableAllFeatures()
  extractor.enableFeatureClassByName('ngtdm')

  featureMap = extractor.execute(image, mask, voxelBased=True)

  for featureName, featureValue in six.iteritems(featureMap):
    if isinstance(featureValue, sitk.Image):
      fileFolder = './dataset/ngtdm/kernel5-radius5/non_tumor/%s' % (fileId)
      if path.exists(fileFolder) == False:
        os.mkdir(fileFolder)
      sitk.WriteImage(featureValue, '%s/%s.nrrd' % (fileFolder, featureName))
      print('Computed %s, stored as "%s/%s.nrrd"' % (featureName, fileFolder, featureName))
    # else:
    #   print('%s: %s' % (featureName, featureValue))

monitorFilePath = './dataset/ngtdm/kernel5-radius5/non_tumor.monitor.csv'
monitor = pd.read_csv(monitorFilePath, index_col='no')
for i, row in monitor.iterrows():
  if row['done'] != 0:
    continue
  fileId = row['file']
  print('Starting %s' % (fileId))
  featureExtractor(fileId)
  monitor.at[i, 'done'] = 1
  monitor.to_csv(monitorFilePath)
# Out:
# ERROR:tornado.general:Uncaught exception in ZMQStream callback
# Traceback (most recent call last):
#   File "/workspaces/todo/.venv/lib/python3.9/site-packages/traitlets/traitlets.py", line 651, in get
#     value = obj._trait_values[self.name]
# KeyError: '_control_lock'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/workspaces/todo/.venv/lib/python3.9/site-packages/zmq/eventloop/zmqstream.py", line 565, in _log_error
#     f.result()
#   File "/workspaces/todo/.venv/lib/python3.9/site-packages/ipykernel/kernelbase.py", line 301, in dispatch_control
#     async with self._control_lock:
#   File "/workspaces/todo/.venv/lib/python3.9/site-packages/traitlets/traitlets.py", line 706, in __get__
#     return self.get(obj, cls)  # type:ignore[return-value]
#   File "/workspaces/todo/.venv/lib/python3.9/site-packages/traitlets/traitlets.py", line 668, in get
#     value = self._validate(obj, default)
#   File "/workspaces/todo/.venv/lib/python3.9/site-packages/traitlets/traitlets.py", line 741, in _validate
#     value = self.validate(obj, value)
#   File "/workspaces/todo/.venv/lib/python3.9/site-packages/traitlets/traitlets.py", line 2319, in validate
#     self.error(obj, value)
#   File "/workspaces/todo/.venv/lib/python3.9/site-packages/traitlets/traitlets.py", line 850, in error
#     raise TraitError(e)
# traitlets.traitlets.TraitError: The '_control_lock' trait of an IPythonKernel instance expected a Lock, not the NoneType None.
# Starting BraTS2021_00580
# Computed original_ngtdm_Busyness, stored as "./dataset/ngtdm/kernel5-radius5/non_tumor/BraTS2021_00580/original_ngtdm_Busyness.nrrd"
# Computed original_ngtdm_Coarseness, stored as "./dataset/ngtdm/kernel5-radius5/non_tumor/BraTS2021_00580/original_ngtdm_Coarseness.nrrd"
# Computed original_ngtdm_Complexity, stored as "./dataset/ngtdm/kernel5-radius5/non_tumor/BraTS2021_00580/original_ngtdm_Complexity.nrrd"
# Computed original_ngtdm_Contrast, stored as "./dataset/ngtdm/kernel5-radius5/non_tumor/BraTS2021_00580/original_ngtdm_Contrast.nrrd"
# Computed original_ngtdm_Strength, stored as "./dataset/ngtdm/kernel5-radius5/non_tumor/BraTS2021_00580/original_ngtdm_Strength.nrrd"
# Starting BraTS2021_00581
# Computed original_ngtdm_Busyness, stored as "./dataset/ngtdm/kernel5-radius5/non_tumor/BraTS2021_00581/original_ngtdm_Busyness.nrrd"
# Computed original_ngtdm_Coarseness, stored as "./dataset/ngtdm/kernel5-radius5/non_tumor/BraTS2021_00581/original_ngtdm_Coarseness.nrrd"
# Computed original_ngtdm_Complexity, stored as "./dataset/ngtdm/kernel5-radius5/non_tumor/BraTS2021_00581/original_ngtdm_Complexity.nrrd"
# Computed original_ngtdm_Contrast, stored as "./dataset/ngtdm/kernel5-radius5/non_tumor/BraTS2021_00581/original_ngtdm_Contrast.nrrd"
# Computed original_ngtdm_Strength, stored as "./dataset/ngtdm/kernel5-radius5/non_tumor/BraTS2021_00581/original_ngtdm_Strength.nrrd"
# Starting BraTS2021_00582
# Computed original_ngtdm_Busyness, stored as "./dataset/ngtdm/kernel5-radius5/non_tumor/BraTS2021_00582/original_ngtdm_Busyness.nrrd"
# Computed original_ngtdm_Coarseness, stored as "./dataset/ngtdm/kernel5-radius5/non_tumor/BraTS2021_00582/original_ngtdm_Coarseness.nrrd"
# Computed original_ngtdm_Complexity, stored as "./dataset/ngtdm/kernel5-radius5/non_tumor/BraTS2021_00582/original_ngtdm_Complexity.nrrd"
# Computed original_ngtdm_Contrast, stored as "./dataset/ngtdm/kernel5-radius5/non_tumor/BraTS2021_00582/original_ngtdm_Contrast.nrrd"
# Computed original_ngtdm_Strength, stored as "./dataset/ngtdm/kernel5-radius5/non_tumor/BraTS2021_00582/original_ngtdm_Strength.nrrd"
# Starting BraTS2021_00583
# Computed original_ngtdm_Busyness, stored as "./dataset/ngtdm/kernel5-radius5/non_tumor/BraTS2021_00583/original_ngtdm_Busyness.nrrd"
# Computed original_ngtdm_Coarseness, stored as "./dataset/ngtdm/kernel5-radius5/non_tumor/BraTS2021_00583/original_ngtdm_Coarseness.nrrd"
# Computed original_ngtdm_Complexity, stored as "./dataset/ngtdm/kernel5-radius5/non_tumor/BraTS2021_00583/original_ngtdm_Complexity.nrrd"
# Computed original_ngtdm_Contrast, stored as "./dataset/ngtdm/kernel5-radius5/non_tumor/BraTS2021_00583/original_ngtdm_Contrast.nrrd"
# Computed original_ngtdm_Strength, stored as "./dataset/ngtdm/kernel5-radius5/non_tumor/BraTS2021_00583/original_ngtdm_Strength.nrrd"
# Starting BraTS2021_00584
# Computed original_ngtdm_Busyness, stored as "./dataset/ngtdm/kernel5-radius5/non_tumor/BraTS2021_00584/original_ngtdm_Busyness.nrrd"
# Computed original_ngtdm_Coarseness, stored as "./dataset/ngtdm/kernel5-radius5/non_tumor/BraTS2021_00584/original_ngtdm_Coarseness.nrrd"
# Computed original_ngtdm_Complexity, stored as "./dataset/ngtdm/kernel5-radius5/non_tumor/BraTS2021_00584/original_ngtdm_Complexity.nrrd"
# Computed original_ngtdm_Contrast, stored as "./dataset/ngtdm/kernel5-radius5/non_tumor/BraTS2021_00584/original_ngtdm_Contrast.nrrd"
# Computed original_ngtdm_Strength, stored as "./dataset/ngtdm/kernel5-radius5/non_tumor/BraTS2021_00584/original_ngtdm_Strength.nrrd"
# Starting BraTS2021_00586
# Computed original_ngtdm_Busyness, stored as "./dataset/ngtdm/kernel5-radius5/non_tumor/BraTS2021_00586/original_ngtdm_Busyness.nrrd"
# Computed original_ngtdm_Coarseness, stored as "./dataset/ngtdm/kernel5-radius5/non_tumor/BraTS2021_00586/original_ngtdm_Coarseness.nrrd"
# Computed original_ngtdm_Complexity, stored as "./dataset/ngtdm/kernel5-radius5/non_tumor/BraTS2021_00586/original_ngtdm_Complexity.nrrd"
# Computed original_ngtdm_Contrast, stored as "./dataset/ngtdm/kernel5-radius5/non_tumor/BraTS2021_00586/original_ngtdm_Contrast.nrrd"
# Computed original_ngtdm_Strength, stored as "./dataset/ngtdm/kernel5-radius5/non_tumor/BraTS2021_00586/original_ngtdm_Strength.nrrd"
# Starting BraTS2021_00587
# Computed original_ngtdm_Busyness, stored as "./dataset/ngtdm/kernel5-radius5/non_tumor/BraTS2021_00587/original_ngtdm_Busyness.nrrd"
# Computed original_ngtdm_Coarseness, stored as "./dataset/ngtdm/kernel5-radius5/non_tumor/BraTS2021_00587/original_ngtdm_Coarseness.nrrd"
# Computed original_ngtdm_Complexity, stored as "./dataset/ngtdm/kernel5-radius5/non_tumor/BraTS2021_00587/original_ngtdm_Complexity.nrrd"
# Computed original_ngtdm_Contrast, stored as "./dataset/ngtdm/kernel5-radius5/non_tumor/BraTS2021_00587/original_ngtdm_Contrast.nrrd"
# Computed original_ngtdm_Strength, stored as "./dataset/ngtdm/kernel5-radius5/non_tumor/BraTS2021_00587/original_ngtdm_Strength.nrrd"
# Starting BraTS2021_00588
# Computed original_ngtdm_Busyness, stored as "./dataset/ngtdm/kernel5-radius5/non_tumor/BraTS2021_00588/original_ngtdm_Busyness.nrrd"
# Computed original_ngtdm_Coarseness, stored as "./dataset/ngtdm/kernel5-radius5/non_tumor/BraTS2021_00588/original_ngtdm_Coarseness.nrrd"
# Computed original_ngtdm_Complexity, stored as "./dataset/ngtdm/kernel5-radius5/non_tumor/BraTS2021_00588/original_ngtdm_Complexity.nrrd"
# Computed original_ngtdm_Contrast, stored as "./dataset/ngtdm/kernel5-radius5/non_tumor/BraTS2021_00588/original_ngtdm_Contrast.nrrd"
# Computed original_ngtdm_Strength, stored as "./dataset/ngtdm/kernel5-radius5/non_tumor/BraTS2021_00588/original_ngtdm_Strength.nrrd"
# Starting BraTS2021_00589
# Computed original_ngtdm_Busyness, stored as "./dataset/ngtdm/kernel5-radius5/non_tumor/BraTS2021_00589/original_ngtdm_Busyness.nrrd"
# Computed original_ngtdm_Coarseness, stored as "./dataset/ngtdm/kernel5-radius5/non_tumor/BraTS2021_00589/original_ngtdm_Coarseness.nrrd"
# Computed original_ngtdm_Complexity, stored as "./dataset/ngtdm/kernel5-radius5/non_tumor/BraTS2021_00589/original_ngtdm_Complexity.nrrd"
# Computed original_ngtdm_Contrast, stored as "./dataset/ngtdm/kernel5-radius5/non_tumor/BraTS2021_00589/original_ngtdm_Contrast.nrrd"
# Computed original_ngtdm_Strength, stored as "./dataset/ngtdm/kernel5-radius5/non_tumor/BraTS2021_00589/original_ngtdm_Strength.nrrd"
# Starting BraTS2021_00590
# Computed original_ngtdm_Busyness, stored as "./dataset/ngtdm/kernel5-radius5/non_tumor/BraTS2021_00590/original_ngtdm_Busyness.nrrd"
# Computed original_ngtdm_Coarseness, stored as "./dataset/ngtdm/kernel5-radius5/non_tumor/BraTS2021_00590/original_ngtdm_Coarseness.nrrd"
# Computed original_ngtdm_Complexity, stored as "./dataset/ngtdm/kernel5-radius5/non_tumor/BraTS2021_00590/original_ngtdm_Complexity.nrrd"
# Computed original_ngtdm_Contrast, stored as "./dataset/ngtdm/kernel5-radius5/non_tumor/BraTS2021_00590/original_ngtdm_Contrast.nrrd"
# Computed original_ngtdm_Strength, stored as "./dataset/ngtdm/kernel5-radius5/non_tumor/BraTS2021_00590/original_ngtdm_Strength.nrrd"
# Starting BraTS2021_00591
# Computed original_ngtdm_Busyness, stored as "./dataset/ngtdm/kernel5-radius5/non_tumor/BraTS2021_00591/original_ngtdm_Busyness.nrrd"
# Computed original_ngtdm_Coarseness, stored as "./dataset/ngtdm/kernel5-radius5/non_tumor/BraTS2021_00591/original_ngtdm_Coarseness.nrrd"
# Computed original_ngtdm_Complexity, stored as "./dataset/ngtdm/kernel5-radius5/non_tumor/BraTS2021_00591/original_ngtdm_Complexity.nrrd"
# Computed original_ngtdm_Contrast, stored as "./dataset/ngtdm/kernel5-radius5/non_tumor/BraTS2021_00591/original_ngtdm_Contrast.nrrd"
# Computed original_ngtdm_Strength, stored as "./dataset/ngtdm/kernel5-radius5/non_tumor/BraTS2021_00591/original_ngtdm_Strength.nrrd"
# Starting BraTS2021_00593
# Computed original_ngtdm_Busyness, stored as "./dataset/ngtdm/kernel5-radius5/non_tumor/BraTS2021_00593/original_ngtdm_Busyness.nrrd"
# Computed original_ngtdm_Coarseness, stored as "./dataset/ngtdm/kernel5-radius5/non_tumor/BraTS2021_00593/original_ngtdm_Coarseness.nrrd"
# Computed original_ngtdm_Complexity, stored as "./dataset/ngtdm/kernel5-radius5/non_tumor/BraTS2021_00593/original_ngtdm_Complexity.nrrd"
# Computed original_ngtdm_Contrast, stored as "./dataset/ngtdm/kernel5-radius5/non_tumor/BraTS2021_00593/original_ngtdm_Contrast.nrrd"
# Computed original_ngtdm_Strength, stored as "./dataset/ngtdm/kernel5-radius5/non_tumor/BraTS2021_00593/original_ngtdm_Strength.nrrd"
# Starting BraTS2021_00594
# Computed original_ngtdm_Busyness, stored as "./dataset/ngtdm/kernel5-radius5/non_tumor/BraTS2021_00594/original_ngtdm_Busyness.nrrd"
# Computed original_ngtdm_Coarseness, stored as "./dataset/ngtdm/kernel5-radius5/non_tumor/BraTS2021_00594/original_ngtdm_Coarseness.nrrd"
# Computed original_ngtdm_Complexity, stored as "./dataset/ngtdm/kernel5-radius5/non_tumor/BraTS2021_00594/original_ngtdm_Complexity.nrrd"
# Computed original_ngtdm_Contrast, stored as "./dataset/ngtdm/kernel5-radius5/non_tumor/BraTS2021_00594/original_ngtdm_Contrast.nrrd"
# Computed original_ngtdm_Strength, stored as "./dataset/ngtdm/kernel5-radius5/non_tumor/BraTS2021_00594/original_ngtdm_Strength.nrrd"
# Starting BraTS2021_00596
# Computed original_ngtdm_Busyness, stored as "./dataset/ngtdm/kernel5-radius5/non_tumor/BraTS2021_00596/original_ngtdm_Busyness.nrrd"
# Computed original_ngtdm_Coarseness, stored as "./dataset/ngtdm/kernel5-radius5/non_tumor/BraTS2021_00596/original_ngtdm_Coarseness.nrrd"
# Computed original_ngtdm_Complexity, stored as "./dataset/ngtdm/kernel5-radius5/non_tumor/BraTS2021_00596/original_ngtdm_Complexity.nrrd"
# Computed original_ngtdm_Contrast, stored as "./dataset/ngtdm/kernel5-radius5/non_tumor/BraTS2021_00596/original_ngtdm_Contrast.nrrd"
# Computed original_ngtdm_Strength, stored as "./dataset/ngtdm/kernel5-radius5/non_tumor/BraTS2021_00596/original_ngtdm_Strength.nrrd"
# Starting BraTS2021_00597
# Computed original_ngtdm_Busyness, stored as "./dataset/ngtdm/kernel5-radius5/non_tumor/BraTS2021_00597/original_ngtdm_Busyness.nrrd"
# Computed original_ngtdm_Coarseness, stored as "./dataset/ngtdm/kernel5-radius5/non_tumor/BraTS2021_00597/original_ngtdm_Coarseness.nrrd"
# Computed original_ngtdm_Complexity, stored as "./dataset/ngtdm/kernel5-radius5/non_tumor/BraTS2021_00597/original_ngtdm_Complexity.nrrd"
# Computed original_ngtdm_Contrast, stored as "./dataset/ngtdm/kernel5-radius5/non_tumor/BraTS2021_00597/original_ngtdm_Contrast.nrrd"
# Computed original_ngtdm_Strength, stored as "./dataset/ngtdm/kernel5-radius5/non_tumor/BraTS2021_00597/original_ngtdm_Strength.nrrd"
# Starting BraTS2021_00598
# Computed original_ngtdm_Busyness, stored as "./dataset/ngtdm/kernel5-radius5/non_tumor/BraTS2021_00598/original_ngtdm_Busyness.nrrd"
# Computed original_ngtdm_Coarseness, stored as "./dataset/ngtdm/kernel5-radius5/non_tumor/BraTS2021_00598/original_ngtdm_Coarseness.nrrd"
# Computed original_ngtdm_Complexity, stored as "./dataset/ngtdm/kernel5-radius5/non_tumor/BraTS2021_00598/original_ngtdm_Complexity.nrrd"
# Computed original_ngtdm_Contrast, stored as "./dataset/ngtdm/kernel5-radius5/non_tumor/BraTS2021_00598/original_ngtdm_Contrast.nrrd"
# Computed original_ngtdm_Strength, stored as "./dataset/ngtdm/kernel5-radius5/non_tumor/BraTS2021_00598/original_ngtdm_Strength.nrrd"
# Starting BraTS2021_00599
# Computed original_ngtdm_Busyness, stored as "./dataset/ngtdm/kernel5-radius5/non_tumor/BraTS2021_00599/original_ngtdm_Busyness.nrrd"
# Computed original_ngtdm_Coarseness, stored as "./dataset/ngtdm/kernel5-radius5/non_tumor/BraTS2021_00599/original_ngtdm_Coarseness.nrrd"
# Computed original_ngtdm_Complexity, stored as "./dataset/ngtdm/kernel5-radius5/non_tumor/BraTS2021_00599/original_ngtdm_Complexity.nrrd"
# Computed original_ngtdm_Contrast, stored as "./dataset/ngtdm/kernel5-radius5/non_tumor/BraTS2021_00599/original_ngtdm_Contrast.nrrd"
# Computed original_ngtdm_Strength, stored as "./dataset/ngtdm/kernel5-radius5/non_tumor/BraTS2021_00599/original_ngtdm_Strength.nrrd"
# Starting BraTS2021_00601
# Computed original_ngtdm_Busyness, stored as "./dataset/ngtdm/kernel5-radius5/non_tumor/BraTS2021_00601/original_ngtdm_Busyness.nrrd"
# Computed original_ngtdm_Coarseness, stored as "./dataset/ngtdm/kernel5-radius5/non_tumor/BraTS2021_00601/original_ngtdm_Coarseness.nrrd"
# Computed original_ngtdm_Complexity, stored as "./dataset/ngtdm/kernel5-radius5/non_tumor/BraTS2021_00601/original_ngtdm_Complexity.nrrd"
# Computed original_ngtdm_Contrast, stored as "./dataset/ngtdm/kernel5-radius5/non_tumor/BraTS2021_00601/original_ngtdm_Contrast.nrrd"
# Computed original_ngtdm_Strength, stored as "./dataset/ngtdm/kernel5-radius5/non_tumor/BraTS2021_00601/original_ngtdm_Strength.nrrd"
# Starting BraTS2021_00602
# Computed original_ngtdm_Busyness, stored as "./dataset/ngtdm/kernel5-radius5/non_tumor/BraTS2021_00602/original_ngtdm_Busyness.nrrd"
# Computed original_ngtdm_Coarseness, stored as "./dataset/ngtdm/kernel5-radius5/non_tumor/BraTS2021_00602/original_ngtdm_Coarseness.nrrd"
# Computed original_ngtdm_Complexity, stored as "./dataset/ngtdm/kernel5-radius5/non_tumor/BraTS2021_00602/original_ngtdm_Complexity.nrrd"
# Computed original_ngtdm_Contrast, stored as "./dataset/ngtdm/kernel5-radius5/non_tumor/BraTS2021_00602/original_ngtdm_Contrast.nrrd"
# Computed original_ngtdm_Strength, stored as "./dataset/ngtdm/kernel5-radius5/non_tumor/BraTS2021_00602/original_ngtdm_Strength.nrrd"
# Starting BraTS2021_00604
# Computed original_ngtdm_Busyness, stored as "./dataset/ngtdm/kernel5-radius5/non_tumor/BraTS2021_00604/original_ngtdm_Busyness.nrrd"
# Computed original_ngtdm_Coarseness, stored as "./dataset/ngtdm/kernel5-radius5/non_tumor/BraTS2021_00604/original_ngtdm_Coarseness.nrrd"
# Computed original_ngtdm_Complexity, stored as "./dataset/ngtdm/kernel5-radius5/non_tumor/BraTS2021_00604/original_ngtdm_Complexity.nrrd"
# Computed original_ngtdm_Contrast, stored as "./dataset/ngtdm/kernel5-radius5/non_tumor/BraTS2021_00604/original_ngtdm_Contrast.nrrd"
# Computed original_ngtdm_Strength, stored as "./dataset/ngtdm/kernel5-radius5/non_tumor/BraTS2021_00604/original_ngtdm_Strength.nrrd"
# Starting BraTS2021_00605
# Computed original_ngtdm_Busyness, stored as "./dataset/ngtdm/kernel5-radius5/non_tumor/BraTS2021_00605/original_ngtdm_Busyness.nrrd"
# Computed original_ngtdm_Coarseness, stored as "./dataset/ngtdm/kernel5-radius5/non_tumor/BraTS2021_00605/original_ngtdm_Coarseness.nrrd"
# Computed original_ngtdm_Complexity, stored as "./dataset/ngtdm/kernel5-radius5/non_tumor/BraTS2021_00605/original_ngtdm_Complexity.nrrd"
# Computed original_ngtdm_Contrast, stored as "./dataset/ngtdm/kernel5-radius5/non_tumor/BraTS2021_00605/original_ngtdm_Contrast.nrrd"
# Computed original_ngtdm_Strength, stored as "./dataset/ngtdm/kernel5-radius5/non_tumor/BraTS2021_00605/original_ngtdm_Strength.nrrd"
# Starting BraTS2021_00606
# Computed original_ngtdm_Busyness, stored as "./dataset/ngtdm/kernel5-radius5/non_tumor/BraTS2021_00606/original_ngtdm_Busyness.nrrd"
# Computed original_ngtdm_Coarseness, stored as "./dataset/ngtdm/kernel5-radius5/non_tumor/BraTS2021_00606/original_ngtdm_Coarseness.nrrd"
# Computed original_ngtdm_Complexity, stored as "./dataset/ngtdm/kernel5-radius5/non_tumor/BraTS2021_00606/original_ngtdm_Complexity.nrrd"
# Computed original_ngtdm_Contrast, stored as "./dataset/ngtdm/kernel5-radius5/non_tumor/BraTS2021_00606/original_ngtdm_Contrast.nrrd"
# Computed original_ngtdm_Strength, stored as "./dataset/ngtdm/kernel5-radius5/non_tumor/BraTS2021_00606/original_ngtdm_Strength.nrrd"
# Starting BraTS2021_00607
# Computed original_ngtdm_Busyness, stored as "./dataset/ngtdm/kernel5-radius5/non_tumor/BraTS2021_00607/original_ngtdm_Busyness.nrrd"
# Computed original_ngtdm_Coarseness, stored as "./dataset/ngtdm/kernel5-radius5/non_tumor/BraTS2021_00607/original_ngtdm_Coarseness.nrrd"
# Computed original_ngtdm_Complexity, stored as "./dataset/ngtdm/kernel5-radius5/non_tumor/BraTS2021_00607/original_ngtdm_Complexity.nrrd"
# Computed original_ngtdm_Contrast, stored as "./dataset/ngtdm/kernel5-radius5/non_tumor/BraTS2021_00607/original_ngtdm_Contrast.nrrd"
# Computed original_ngtdm_Strength, stored as "./dataset/ngtdm/kernel5-radius5/non_tumor/BraTS2021_00607/original_ngtdm_Strength.nrrd"
# Starting BraTS2021_00608
# Computed original_ngtdm_Busyness, stored as "./dataset/ngtdm/kernel5-radius5/non_tumor/BraTS2021_00608/original_ngtdm_Busyness.nrrd"
# Computed original_ngtdm_Coarseness, stored as "./dataset/ngtdm/kernel5-radius5/non_tumor/BraTS2021_00608/original_ngtdm_Coarseness.nrrd"
# Computed original_ngtdm_Complexity, stored as "./dataset/ngtdm/kernel5-radius5/non_tumor/BraTS2021_00608/original_ngtdm_Complexity.nrrd"
# Computed original_ngtdm_Contrast, stored as "./dataset/ngtdm/kernel5-radius5/non_tumor/BraTS2021_00608/original_ngtdm_Contrast.nrrd"
# Computed original_ngtdm_Strength, stored as "./dataset/ngtdm/kernel5-radius5/non_tumor/BraTS2021_00608/original_ngtdm_Strength.nrrd"
# Starting BraTS2021_00610
# Computed original_ngtdm_Busyness, stored as "./dataset/ngtdm/kernel5-radius5/non_tumor/BraTS2021_00610/original_ngtdm_Busyness.nrrd"
# Computed original_ngtdm_Coarseness, stored as "./dataset/ngtdm/kernel5-radius5/non_tumor/BraTS2021_00610/original_ngtdm_Coarseness.nrrd"
# Computed original_ngtdm_Complexity, stored as "./dataset/ngtdm/kernel5-radius5/non_tumor/BraTS2021_00610/original_ngtdm_Complexity.nrrd"
# Computed original_ngtdm_Contrast, stored as "./dataset/ngtdm/kernel5-radius5/non_tumor/BraTS2021_00610/original_ngtdm_Contrast.nrrd"
# Computed original_ngtdm_Strength, stored as "./dataset/ngtdm/kernel5-radius5/non_tumor/BraTS2021_00610/original_ngtdm_Strength.nrrd"
# Starting BraTS2021_00611
# Computed original_ngtdm_Busyness, stored as "./dataset/ngtdm/kernel5-radius5/non_tumor/BraTS2021_00611/original_ngtdm_Busyness.nrrd"
# Computed original_ngtdm_Coarseness, stored as "./dataset/ngtdm/kernel5-radius5/non_tumor/BraTS2021_00611/original_ngtdm_Coarseness.nrrd"
# Computed original_ngtdm_Complexity, stored as "./dataset/ngtdm/kernel5-radius5/non_tumor/BraTS2021_00611/original_ngtdm_Complexity.nrrd"
# Computed original_ngtdm_Contrast, stored as "./dataset/ngtdm/kernel5-radius5/non_tumor/BraTS2021_