# %%
import radiomics
import numpy as np
import SimpleITK as sitk
import radiomics.featureextractor
import os
import six
from os import path
import pandas as pd

def featureExtractor(fileId):
  imagePath = './dataset/BraTS2021_Training_Data/%s/%s_flair.nii.gz' % (fileId, fileId)
  image = sitk.ReadImage(imagePath)
  maskPath ='./dataset/BraTS2021_Training_Data/%s/%s_kernel5_tumor.nii.gz' % (fileId, fileId)
  mask = sitk.ReadImage(maskPath)

  kernel = 5
  settings = {}
  settings['kernelRadius'] = kernel
  settings['maskedKernel'] = False
  settings['voxelBatch'] = 40000
  extractor = radiomics.featureextractor.RadiomicsFeatureExtractor(**settings)
  extractor.disableAllFeatures()
  extractor.enableFeatureClassByName('glszm')

  featureMap = extractor.execute(image, mask, voxelBased=True)

  for featureName, featureValue in six.iteritems(featureMap):
    if isinstance(featureValue, sitk.Image):
      fileFolder = './dataset/glszm/kernel5-radius5/tumor/%s' % (fileId)
      if path.exists(fileFolder) == False:
        os.mkdir(fileFolder)
      sitk.WriteImage(featureValue, '%s/%s.nrrd' % (fileFolder, featureName))
      print('Computed %s, stored as "%s/%s.nrrd"' % (featureName, fileFolder, featureName))
    # else:
    #   print('%s: %s' % (featureName, featureValue))

monitorFilePath = './dataset/glszm/kernel5-radius5/tumor.monitor.csv'
monitor = pd.read_csv(monitorFilePath, index_col='no')
for i, row in monitor.iterrows():
  if row['done'] != 0:
    continue
  fileId = row['file']
  print('Starting %s' % (fileId))
  featureExtractor(fileId)
  monitor.at[i, 'done'] = 1
  monitor.to_csv(monitorFilePath)
# Out:
# Starting BraTS2021_00140
# Computed original_glszm_GrayLevelNonUniformity, stored as "./dataset/glszm/kernel5-radius5/tumor/BraTS2021_00140/original_glszm_GrayLevelNonUniformity.nrrd"
# Computed original_glszm_GrayLevelNonUniformityNormalized, stored as "./dataset/glszm/kernel5-radius5/tumor/BraTS2021_00140/original_glszm_GrayLevelNonUniformityNormalized.nrrd"
# Computed original_glszm_GrayLevelVariance, stored as "./dataset/glszm/kernel5-radius5/tumor/BraTS2021_00140/original_glszm_GrayLevelVariance.nrrd"
# Computed original_glszm_HighGrayLevelZoneEmphasis, stored as "./dataset/glszm/kernel5-radius5/tumor/BraTS2021_00140/original_glszm_HighGrayLevelZoneEmphasis.nrrd"
# Computed original_glszm_LargeAreaEmphasis, stored as "./dataset/glszm/kernel5-radius5/tumor/BraTS2021_00140/original_glszm_LargeAreaEmphasis.nrrd"
# Computed original_glszm_LargeAreaHighGrayLevelEmphasis, stored as "./dataset/glszm/kernel5-radius5/tumor/BraTS2021_00140/original_glszm_LargeAreaHighGrayLevelEmphasis.nrrd"
# Computed original_glszm_LargeAreaLowGrayLevelEmphasis, stored as "./dataset/glszm/kernel5-radius5/tumor/BraTS2021_00140/original_glszm_LargeAreaLowGrayLevelEmphasis.nrrd"
# Computed original_glszm_LowGrayLevelZoneEmphasis, stored as "./dataset/glszm/kernel5-radius5/tumor/BraTS2021_00140/original_glszm_LowGrayLevelZoneEmphasis.nrrd"
# Computed original_glszm_SizeZoneNonUniformity, stored as "./dataset/glszm/kernel5-radius5/tumor/BraTS2021_00140/original_glszm_SizeZoneNonUniformity.nrrd"
# Computed original_glszm_SizeZoneNonUniformityNormalized, stored as "./dataset/glszm/kernel5-radius5/tumor/BraTS2021_00140/original_glszm_SizeZoneNonUniformityNormalized.nrrd"
# Computed original_glszm_SmallAreaEmphasis, stored as "./dataset/glszm/kernel5-radius5/tumor/BraTS2021_00140/original_glszm_SmallAreaEmphasis.nrrd"
# Computed original_glszm_SmallAreaHighGrayLevelEmphasis, stored as "./dataset/glszm/kernel5-radius5/tumor/BraTS2021_00140/original_glszm_SmallAreaHighGrayLevelEmphasis.nrrd"
# Computed original_glszm_SmallAreaLowGrayLevelEmphasis, stored as "./dataset/glszm/kernel5-radius5/tumor/BraTS2021_00140/original_glszm_SmallAreaLowGrayLevelEmphasis.nrrd"
# Computed original_glszm_ZoneEntropy, stored as "./dataset/glszm/kernel5-radius5/tumor/BraTS2021_00140/original_glszm_ZoneEntropy.nrrd"
# Computed original_glszm_ZonePercentage, stored as "./dataset/glszm/kernel5-radius5/tumor/BraTS2021_00140/original_glszm_ZonePercentage.nrrd"
# Computed original_glszm_ZoneVariance, stored as "./dataset/glszm/kernel5-radius5/tumor/BraTS2021_00140/original_glszm_ZoneVariance.nrrd"
# Starting BraTS2021_00142
# Computed original_glszm_GrayLevelNonUniformity, stored as "./dataset/glszm/kernel5-radius5/tumor/BraTS2021_00142/original_glszm_GrayLevelNonUniformity.nrrd"
# Computed original_glszm_GrayLevelNonUniformityNormalized, stored as "./dataset/glszm/kernel5-radius5/tumor/BraTS2021_00142/original_glszm_GrayLevelNonUniformityNormalized.nrrd"
# Computed original_glszm_GrayLevelVariance, stored as "./dataset/glszm/kernel5-radius5/tumor/BraTS2021_00142/original_glszm_GrayLevelVariance.nrrd"
# Computed original_glszm_HighGrayLevelZoneEmphasis, stored as "./dataset/glszm/kernel5-radius5/tumor/BraTS2021_00142/original_glszm_HighGrayLevelZoneEmphasis.nrrd"
# Computed original_glszm_LargeAreaEmphasis, stored as "./dataset/glszm/kernel5-radius5/tumor/BraTS2021_00142/original_glszm_LargeAreaEmphasis.nrrd"
# Computed original_glszm_LargeAreaHighGrayLevelEmphasis, stored as "./dataset/glszm/kernel5-radius5/tumor/BraTS2021_00142/original_glszm_LargeAreaHighGrayLevelEmphasis.nrrd"
# Computed original_glszm_LargeAreaLowGrayLevelEmphasis, stored as "./dataset/glszm/kernel5-radius5/tumor/BraTS2021_00142/original_glszm_LargeAreaLowGrayLevelEmphasis.nrrd"
# Computed original_glszm_LowGrayLevelZoneEmphasis, stored as "./dataset/glszm/kernel5-radius5/tumor/BraTS2021_00142/original_glszm_LowGrayLevelZoneEmphasis.nrrd"
# Computed original_glszm_SizeZoneNonUniformity, stored as "./dataset/glszm/kernel5-radius5/tumor/BraTS2021_00142/original_glszm_SizeZoneNonUniformity.nrrd"
# Computed original_glszm_SizeZoneNonUniformityNormalized, stored as "./dataset/glszm/kernel5-radius5/tumor/BraTS2021_00142/original_glszm_SizeZoneNonUniformityNormalized.nrrd"
# Computed original_glszm_SmallAreaEmphasis, stored as "./dataset/glszm/kernel5-radius5/tumor/BraTS2021_00142/original_glszm_SmallAreaEmphasis.nrrd"
# Computed original_glszm_SmallAreaHighGrayLevelEmphasis, stored as "./dataset/glszm/kernel5-radius5/tumor/BraTS2021_00142/original_glszm_SmallAreaHighGrayLevelEmphasis.nrrd"
# Computed original_glszm_SmallAreaLowGrayLevelEmphasis, stored as "./dataset/glszm/kernel5-radius5/tumor/BraTS2021_00142/original_glszm_SmallAreaLowGrayLevelEmphasis.nrrd"
# Computed original_glszm_ZoneEntropy, stored as "./dataset/glszm/kernel5-radius5/tumor/BraTS2021_00142/original_glszm_ZoneEntropy.nrrd"
# Computed original_glszm_ZonePercentage, stored as "./dataset/glszm/kernel5-radius5/tumor/BraTS2021_00142/original_glszm_ZonePercentage.nrrd"
# Computed original_glszm_ZoneVariance, stored as "./dataset/glszm/kernel5-radius5/tumor/BraTS2021_00142/original_glszm_ZoneVariance.nrrd"
# Starting BraTS2021_00143
# Computed original_glszm_GrayLevelNonUniformity, stored as "./dataset/glszm/kernel5-radius5/tumor/BraTS2021_00143/original_glszm_GrayLevelNonUniformity.nrrd"
# Computed original_glszm_GrayLevelNonUniformityNormalized, stored as "./dataset/glszm/kernel5-radius5/tumor/BraTS2021_00143/original_glszm_GrayLevelNonUniformityNormalized.nrrd"
# Computed original_glszm_GrayLevelVariance, stored as "./dataset/glszm/kernel5-radius5/tumor/BraTS2021_00143/original_glszm_GrayLevelVariance.nrrd"
# Computed original_glszm_HighGrayLevelZoneEmphasis, stored as "./dataset/glszm/kernel5-radius5/tumor/BraTS2021_00143/original_glszm_HighGrayLevelZoneEmphasis.nrrd"
# Computed original_glszm_LargeAreaEmphasis, stored as "./dataset/glszm/kernel5-radius5/tumor/BraTS2021_00143/original_glszm_LargeAreaEmphasis.nrrd"
# Computed original_glszm_LargeAreaHighGrayLevelEmphasis, stored as "./dataset/glszm/kernel5-radius5/tumor/BraTS2021_00143/original_glszm_LargeAreaHighGrayLevelEmphasis.nrrd"
# Computed original_glszm_LargeAreaLowGrayLevelEmphasis, stored as "./dataset/glszm/kernel5-radius5/tumor/BraTS2021_00143/original_glszm_LargeAreaLowGrayLevelEmphasis.nrrd"
# Computed original_glszm_LowGrayLevelZoneEmphasis, stored as "./dataset/glszm/kernel5-radius5/tumor/BraTS2021_00143/original_glszm_LowGrayLevelZoneEmphasis.nrrd"
# Computed original_glszm_SizeZoneNonUniformity, stored as "./dataset/glszm/kernel5-radius5/tumor/BraTS2021_00143/original_glszm_SizeZoneNonUniformity.nrrd"
# Computed original_glszm_SizeZoneNonUniformityNormalized, stored as "./dataset/glszm/kernel5-radius5/tumor/BraTS2021_00143/original_glszm_SizeZoneNonUniformityNormalized.nrrd"
# Computed original_glszm_SmallAreaEmphasis, stored as "./dataset/glszm/kernel5-radius5/tumor/BraTS2021_00143/original_glszm_SmallAreaEmphasis.nrrd"
# Computed original_glszm_SmallAreaHighGrayLevelEmphasis, stored as "./dataset/glszm/kernel5-radius5/tumor/BraTS2021_00143/original_glszm_SmallAreaHighGrayLevelEmphasis.nrrd"
# Computed original_glszm_SmallAreaLowGrayLevelEmphasis, stored as "./dataset/glszm/kernel5-radius5/tumor/BraTS2021_00143/original_glszm_SmallAreaLowGrayLevelEmphasis.nrrd"
# Computed original_glszm_ZoneEntropy, stored as "./dataset/glszm/kernel5-radius5/tumor/BraTS2021_00143/original_glszm_ZoneEntropy.nrrd"
# Computed original_glszm_ZonePercentage, stored as "./dataset/glszm/kernel5-radius5/tumor/BraTS2021_00143/original_glszm_ZonePercentage.nrrd"
# Computed original_glszm_ZoneVariance, stored as "./dataset/glszm/kernel5-radius5/tumor/BraTS2021_00143/original_glszm_ZoneVariance.nrrd"
# Starting BraTS2021_00144
# Computed original_glszm_GrayLevelNonUniformity, stored as "./dataset/glszm/kernel5-radius5/tumor/BraTS2021_00144/original_glszm_GrayLevelNonUniformity.nrrd"
# Computed original_glszm_GrayLevelNonUniformityNormalized, stored as "./dataset/glszm/kernel5-radius5/tumor/BraTS2021_00144/original_glszm_GrayLevelNonUniformityNormalized.nrrd"
# Computed original_glszm_GrayLevelVariance, stored as "./dataset/glszm/kernel5-radius5/tumor/BraTS2021_00144/original_glszm_GrayLevelVariance.nrrd"
# Computed original_glszm_HighGrayLevelZoneEmphasis, stored as "./dataset/glszm/kernel5-radius5/tumor/BraTS2021_00144/original_glszm_HighGrayLevelZoneEmphasis.nrrd"
# Computed original_glszm_LargeAreaEmphasis, stored as "./dataset/glszm/kernel5-radius5/tumor/BraTS2021_00144/original_glszm_LargeAreaEmphasis.nrrd"
# Computed original_glszm_LargeAreaHighGrayLevelEmphasis, stored as "./dataset/glszm/kernel5-radius5/tumor/BraTS2021_00144/original_glszm_LargeAreaHighGrayLevelEmphasis.nrrd"
# Computed original_glszm_LargeAreaLowGrayLevelEmphasis, stored as "./dataset/glszm/kernel5-radius5/tumor/BraTS2021_00144/original_glszm_LargeAreaLowGrayLevelEmphasis.nrrd"
# Computed original_glszm_LowGrayLevelZoneEmphasis, stored as "./dataset/glszm/kernel5-radius5/tumor/BraTS2021_00144/original_glszm_LowGrayLevelZoneEmphasis.nrrd"
# Computed original_glszm_SizeZoneNonUniformity, stored as "./dataset/glszm/kernel5-radius5/tumor/BraTS2021_00144/original_glszm_SizeZoneNonUniformity.nrrd"
# Computed original_glszm_SizeZoneNonUniformityNormalized, stored as "./dataset/glszm/kernel5-radius5/tumor/BraTS2021_00144/original_glszm_SizeZoneNonUniformityNormalized.nrrd"
# Computed original_glszm_SmallAreaEmphasis, stored as "./dataset/glszm/kernel5-radius5/tumor/BraTS2021_00144/original_glszm_SmallAreaEmphasis.nrrd"
# Computed original_glszm_SmallAreaHighGrayLevelEmphasis, stored as "./dataset/glszm/kernel5-radius5/tumor/BraTS2021_00144/original_glszm_SmallAreaHighGrayLevelEmphasis.nrrd"
# Computed original_glszm_SmallAreaLowGrayLevelEmphasis, stored as "./dataset/glszm/kernel5-radius5/tumor/BraTS2021_00144/original_glszm_SmallAreaLowGrayLevelEmphasis.nrrd"
# Computed original_glszm_ZoneEntropy, stored as "./dataset/glszm/kernel5-radius5/tumor/BraTS2021_00144/original_glszm_ZoneEntropy.nrrd"
# Computed original_glszm_ZonePercentage, stored as "./dataset/glszm/kernel5-radius5/tumor/BraTS2021_00144/original_glszm_ZonePercentage.nrrd"
# Computed original_glszm_ZoneVariance, stored as "./dataset/glszm/kernel5-radius5/tumor/BraTS2021_00144/original_glszm_ZoneVariance.nrrd"
# Starting BraTS2021_00146
# Computed original_glszm_GrayLevelNonUniformity, stored as "./dataset/glszm/kernel5-radius5/tumor/BraTS2021_00146/original_glszm_GrayLevelNonUniformity.nrrd"
# Computed original_glszm_GrayLevelNonUniformityNormalized, stored as "./dataset/glszm/kernel5-radius5/tumor/BraTS2021_00146/original_glszm_GrayLevelNonUniformityNormalized.nrrd"
# Computed original_glszm_GrayLevelVariance, stored as "./dataset/glszm/kernel5-radius5/tumor/BraTS2021_00146/original_glszm_GrayLevelVariance.nrrd"
# Computed original_glszm_HighGrayLevelZoneEmphasis, stored as "./dataset/glszm/kernel5-radius5/tumor/BraTS2021_00146/original_glszm_HighGrayLevelZoneEmphasis.nrrd"
# Computed original_glszm_LargeAreaEmphasis, stored as "./dataset/glszm/kernel5-radius5/tumor/BraTS2021_00146/original_glszm_LargeAreaEmphasis.nrrd"
# Computed original_glszm_LargeAreaHighGrayLevelEmphasis, stored as "./dataset/glszm/kernel5-radius5/tumor/BraTS2021_00146/original_glszm_LargeAreaHighGrayLevelEmphasis.nrrd"
# Computed original_glszm_LargeAreaLowGrayLevelEmphasis, stored as "./dataset/glszm/kernel5-radius5/tumor/BraTS2021_00146/original_glszm_LargeAreaLowGrayLevelEmphasis.nrrd"
# Computed original_glszm_LowGrayLevelZoneEmphasis, stored as "./dataset/glszm/kernel5-radius5/tumor/BraTS2021_00146/original_glszm_LowGrayLevelZoneEmphasis.nrrd"
# Computed original_glszm_SizeZoneNonUniformity, stored as "./dataset/glszm/kernel5-radius5/tumor/BraTS2021_00146/original_glszm_SizeZoneNonUniformity.nrrd"
# Computed original_glszm_SizeZoneNonUniformityNormalized, stored as "./dataset/glszm/kernel5-radius5/tumor/BraTS2021_00146/original_glszm_SizeZoneNonUniformityNormalized.nrrd"
# Computed original_glszm_SmallAreaEmphasis, stored as "./dataset/glszm/kernel5-radius5/tumor/BraTS2021_00146/original_glszm_SmallAreaEmphasis.nrrd"
# Computed original_glszm_SmallAreaHighGrayLevelEmphasis, stored as "./dataset/glszm/kernel5-radius5/tumor/BraTS2021_00146/original_glszm_SmallAreaHighGrayLevelEmphasis.nrrd"
# Computed original_glszm_SmallAreaLowGrayLevelEmphasis, stored as "./dataset/glszm/kernel5-radius5/tumor/BraTS2021_00146/original_glszm_SmallAreaLowGrayLevelEmphasis.nrrd"
# Computed original_glszm_ZoneEntropy, stored as "./dataset/glszm/kernel5-radius5/tumor/BraTS2021_00146/original_glszm_ZoneEntropy.nrrd"
# Computed original_glszm_ZonePercentage, stored as "./dataset/glszm/kernel5-radius5/tumor/BraTS2021_00146/original_glszm_ZonePercentage.nrrd"
# Computed original_glszm_ZoneVariance, stored as "./dataset/glszm/kernel5-radius5/tumor/BraTS2021_00146/original_glszm_ZoneVariance.nrrd"
# Starting BraTS2021_00147
# Computed original_glszm_GrayLevelNonUniformity, stored as "./dataset/glszm/kernel5-radius5/tumor/BraTS2021_00147/original_glszm_GrayLevelNonUniformity.nrrd"
# Computed original_glszm_GrayLevelNonUniformityNormalized, stored as "./dataset/glszm/kernel5-radius5/tumor/BraTS2021_00147/original_glszm_GrayLevelNonUniformityNormalized.nrrd"
# Computed original_glszm_GrayLevelVariance, stored as "./dataset/glszm/kernel5-radius5/tumor/BraTS2021_00147/original_glszm_GrayLevelVariance.nrrd"
# Computed original_glszm_HighGrayLevelZoneEmphasis, stored as "./dataset/glszm/kernel5-radius5/tumor/BraTS2021_00147/original_glszm_HighGrayLevelZoneEmphasis.nrrd"
# Computed original_glszm_LargeAreaEmphasis, stored as "./dataset/glszm/kernel5-radius5/tumor/BraTS2021_00147/original_glszm_LargeAreaEmphasis.nrrd"
# Computed original_glszm_LargeAreaHighGrayLevelEmphasis, stored as "./dataset/glszm/kernel5-radius5/tumor/BraTS2021_00147/original_glszm_LargeAreaHighGrayLevelEmphasis.nrrd"
# Computed original_glszm_LargeAreaLowGrayLevelEmphasis, stored as "./dataset/glszm/kernel5-radius5/tumor/BraTS2021_00147/original_glszm_LargeAreaLowGrayLevelEmphasis.nrrd"
# Computed original_glszm_LowGrayLevelZoneEmphasis, stored as "./dataset/glszm/kernel5-radius5/tumor/BraTS2021_00147/original_glszm_LowGrayLevelZoneEmphasis.nrrd"
# Computed original_glszm_SizeZoneNonUniformity, stored as "./dataset/glszm/kernel5-radius5/tumor/BraTS2021_00147/original_glszm_SizeZoneNonUniformity.nrrd"
# Computed original_glszm_SizeZoneNonUniformityNormalized, stored as "./dataset/glszm/kernel5-radius5/tumor/BraTS2021_00147/original_glszm_SizeZoneNonUniformityNormalized.nrrd"
# Computed original_glszm_SmallAreaEmphasis, stored as "./dataset/glszm/kernel5-radius5/tumor/BraTS2021_00147/original_glszm_SmallAreaEmphasis.nrrd"
# Computed original_glszm_SmallAreaHighGrayLevelEmphasis, stored as "./dataset/glszm/kernel5-radius5/tumor/BraTS2021_00147/original_glszm_SmallAreaHighGrayLevelEmphasis.nrrd"
# Computed original_glszm_SmallAreaLowGrayLevelEmphasis, stored as "./dataset/glszm/kernel5-radius5/tumor/BraTS2021_00147/original_glszm_SmallAreaLowGrayLevelEmphasis.nrrd"
# Computed original_glszm_ZoneEntropy, stored as "./dataset/glszm/kernel5-radius5/tumor/BraTS2021_00147/original_glszm_ZoneEntropy.nrrd"
# Computed original_glszm_ZonePercentage, stored as "./dataset/glszm/kernel5-radius5/tumor/BraTS2021_00147/original_glszm_ZonePercentage.nrrd"
# Computed original_glszm_ZoneVariance, stored as "./dataset/glszm/kernel5-radius5/tumor/BraTS2021_00147/original_glszm_ZoneVariance.nrrd"
# Starting BraTS2021_00148
# Computed original_glszm_GrayLevelNonUniformity, stored as "./dataset/glszm/kernel5-radius5/tumor/BraTS2021_00148/original_glszm_GrayLevelNonUniformity.nrrd"
# Computed original_glszm_GrayLevelNonUniformityNormalized, stored as "./dataset/glszm/kernel5-radius5/tumor/BraTS2021_00148/original_glszm_GrayLevelNonUniformityNormalized.nrrd"
# Computed original_glszm_GrayLevelVariance, stored as "./dataset/glszm/kernel5-radius5/tumor/BraTS2021_00148/original_glszm_GrayLevelVariance.nrrd"
# Computed original_glszm_HighGrayLevelZoneEmphasis, stored as "./dataset/glszm/kernel5-radius5/tumor/BraTS2021_00148/original_glszm_HighGrayLevelZoneEmphasis.nrrd"
# Computed original_glszm_LargeAreaEmphasis, stored as "./dataset/glszm/kernel5-radius5/tumor/BraTS2021_00148/original_glszm_LargeAreaEmphasis.nrrd"
# Computed original_glszm_LargeAreaHighGrayLevelEmphasis, stored as "./dataset/glszm/kernel5-radius5/tumor/BraTS2021_00148/original_glszm_LargeAreaHighGrayLevelEmphasis.nrrd"
# Computed original_glszm_LargeAreaLowGrayLevelEmphasis, stored as "./dataset/glszm/kernel5-radius5/tumor/BraTS2021_00148/original_glszm_LargeAreaLowGrayLevelEmphasis.nrrd"
# Computed original_glszm_LowGrayLevelZoneEmphasis, stored as "./dataset/glszm/kernel5-radius5/tumor/BraTS2021_00148/original_glszm_LowGrayLevelZoneEmphasis.nrrd"
# Computed original_glszm_SizeZoneNonUniformity, stored as "./dataset/glszm/kernel5-radius5/tumor/BraTS2021_00148/original_glszm_SizeZoneNonUniformity.nrrd"
# Computed original_glszm_SizeZoneNonUniformityNormalized, stored as "./dataset/glszm/kernel5-radius5/tumor/BraTS2021_00148/original_glszm_SizeZoneNonUniformityNormalized.nrrd"
# Computed original_glszm_SmallAreaEmphasis, stored as "./dataset/glszm/kernel5-radius5/tumor/BraTS2021_00148/original_glszm_SmallAreaEmphasis.nrrd"
# Computed original_glszm_SmallAreaHighGrayLevelEmphasis, stored as "./dataset/glszm/kernel5-radius5/tumor/BraTS2021_00148/original_glszm_SmallAreaHighGrayLevelEmphasis.nrrd"
# Computed original_glszm_SmallAreaLowGrayLevelEmphasis, stored as "./dataset/glszm/kernel5-radius5/tumor/BraTS2021_00148/original_glszm_SmallAreaLowGrayLevelEmphasis.nrrd"
# Computed original_glszm_ZoneEntropy, stored as "./dataset/glszm/kernel5-radius5/tumor/BraTS2021_00148/original_glszm_ZoneEntropy.nrrd"
# Computed original_glszm_ZonePercentage, stored as "./dataset/glszm/kernel5-radius5/tumor/BraTS2021_00148/original_glszm_ZonePercentage.nrrd"
# Computed original_glszm_ZoneVariance, stored as "./dataset/glszm/kernel5-radius5/tumor/BraTS2021_00148/original_glszm_ZoneVariance.nrrd"
# Starting BraTS2021_00149
# Computed original_glszm_GrayLevelNonUniformity, stored as "./dataset/glszm/kernel5-radius5/tumor/BraTS2021_00149/original_glszm_GrayLevelNonUniformity.nrrd"
# Computed original_glszm_GrayLevelNonUniformityNormalized, stored as "./dataset/glszm/kernel5-radius5/tumor/BraTS2021_00149/original_glszm_GrayLevelNonUniformityNormalized.nrrd"
# Computed original_glszm_GrayLevelVariance, stored as "./dataset/glszm/kernel5-radius5/tumor/BraTS2021_00149/original_glszm_GrayLevelVariance.nrrd"
# Computed original_glszm_HighGrayLevelZoneEmphasis, stored as "./dataset/glszm/kernel5-radius5/tumor/BraTS2021_00149/original_glszm_HighGrayLevelZoneEmphasis.nrrd"
# Computed original_glszm_LargeAreaEmphasis, stored as "./dataset/glszm/kernel5-radius5/tumor/BraTS2021_00149/original_glszm_LargeAreaEmphasis.nrrd"
# Computed original_glszm_LargeAreaHighGrayLevelEmphasis, stored as "./dataset/glszm/kernel5-radius5/tumor/BraTS2021_00149/original_glszm_LargeAreaHighGrayLevelEmphasis.nrrd"
# Computed original_glszm_LargeAreaLowGrayLevelEmphasis, stored as "./dataset/glszm/kernel5-radius5/tumor/BraTS2021_00149/original_glszm_LargeAreaLowGrayLevelEmphasis.nrrd"
# Computed original_glszm_LowGrayLevelZoneEmphasis, stored as "./dataset/glszm/kernel5-radius5/tumor/BraTS2021_00149/original_glszm_LowGrayLevelZoneEmphasis.nrrd"
# Computed original_glszm_SizeZoneNonUniformity, stored as "./dataset/glszm/kernel5-radius5/tumor/BraTS2021_00149/original_glszm_SizeZoneNonUniformity.nrrd"
# Computed original_glszm_SizeZoneNonUniformityNormalized, stored as "./dataset/glszm/kernel5-radius5/tumor/BraTS2021_00149/original_glszm_SizeZoneNonUniformityNormalized.nrrd"
# Computed original_glszm_SmallAreaEmphasis, stored as "./dataset/glszm/kernel5-radius5/tumor/BraTS2021_00149/original_glszm_SmallAreaEmphasis.nrrd"
# Computed original_glszm_SmallAreaHighGrayLevelEmphasis, stored as "./dataset/glszm/kernel5-radius5/tumor/BraTS2021_00149/original_glszm_SmallAreaHighGrayLevelEmphasis.nrrd"
# Computed original_glszm_SmallAreaLowGrayLevelEmphasis, stored as "./dataset/glszm/kernel5-radius5/tumor/BraTS2021_00149/original_glszm_SmallAreaLowGrayLevelEmphasis.nrrd"
# Computed original_glszm_ZoneEntropy, stored as "./dataset/glszm/kernel5-radius5/tumor/BraTS2021_00149/original_glszm_ZoneEntropy.nrrd"
# Computed original_glszm_ZonePercentage, stored as "./dataset/glszm/kernel5-radius5/tumor/BraTS2021_00149/original_glszm_ZonePercentage.nrrd"
# Computed original_glszm_ZoneVariance, stored as "./dataset/glszm/kernel5-radius5/tumor/BraTS2021_00149/original_glszm_ZoneVariance.nrrd"
# Starting BraTS2021_00150
# Computed original_glszm_GrayLevelNonUniformity, stored as "./dataset/glszm/kernel5-radius5/tumor/BraTS2021_00150/original_glszm_GrayLevelNonUniformity.nrrd"
# Computed original_glszm_GrayLevelNonUniformityNormalized, stored as "./dataset/glszm/kernel5-radius5/tumor/BraTS2021_00150/original_glszm_GrayLevelNonUniformityNormalized.nrrd"
# Computed original_glszm_GrayLevelVariance, stored as "./dataset/glszm/kernel5-radius5/tumor/BraTS2021_00150/original_glszm_GrayLevelVariance.nrrd"
# Computed original_glszm_HighGrayLevelZoneEmphasis, stored as "./dataset/glszm/kernel5-radius5/tumor/BraTS2021_00150/original_glszm_HighGrayLevelZoneEmphasis.nrrd"
# Computed original_glszm_LargeAreaEmphasis, stored as "./dataset/glszm/kernel5-radius5/tumor/BraTS2021_00150/original_glszm_LargeAreaEmphasis.nrrd"
# Computed original_glszm_LargeAreaHighGrayLevelEmphasis, stored as "./dataset/glszm/kernel5-radius5/tumor/BraTS2021_00150/original_glszm_LargeAreaHighGrayLevelEmphasis.nrrd"
# Computed original_glszm_LargeAreaLowGrayLevelEmphasis, stored as "./dataset/glszm/kernel5-radius5/tumor/BraTS2021_00150/original_glszm_LargeAreaLowGrayLevelEmphasis.nrrd"
# Computed original_glszm_LowGrayLevelZoneEmphasis, stored as "./dataset/glszm/kernel5-radius5/tumor/BraTS2021_00150/original_glszm_LowGrayLevelZoneEmphasis.nrrd"
# Computed original_glszm_SizeZoneNonUniformity, stored as "./dataset/glszm/kernel5-radius5/tumor/BraTS2021_00150/original_glszm_SizeZoneNonUniformity.nrrd"
# Computed original_glszm_SizeZoneNonUniformityNormalized, stored as "./dataset/glszm/kernel5-radius5/tumor/BraTS2021_00150/original_glszm_SizeZoneNonUniformityNormalized.nrrd"
# Computed original_glszm_SmallAreaEmphasis, stored as "./dataset/glszm/kernel5-radius5/tumor/BraTS2021_00150/original_glszm_SmallAreaEmphasis.nrrd"
# Computed original_glszm_SmallAreaHighGrayLevelEmphasis, stored as "./dataset/glszm/kernel5-radius5/tumor/BraTS2021_00150/original_glszm_SmallAreaHighGrayLevelEmphasis.nrrd"
# Computed original_glszm_SmallAreaLowGrayLevelEmphasis, stored as "./dataset/glszm/kernel5-radius5/tumor/BraTS2021_00150/original_glszm_SmallAreaLowGrayLevelEmphasis.nrrd"
# Computed original_glszm_ZoneEntropy, stored as "./dataset/glszm/kernel5-radius5/tumor/BraTS2021_00150/original_glszm_ZoneEntropy.nrrd"
# Computed original_glszm_ZonePercentage, stored as "./dataset/glszm/kernel5-radius5/tumor/BraTS2021_00150/original_glszm_ZonePercentage.nrrd"
# Computed original_glszm_ZoneVariance, stored as "./dataset/glszm/kernel5-radius5/tumor/BraTS2021_00150/original_glszm_ZoneVariance.nrrd"
# Starting BraTS2021_00151
# Computed original_glszm_GrayLevelNonUniformity, stored as "./dataset/glszm/kernel5-radius5/tumor/BraTS2021_00151/original_glszm_GrayLevelNonUniformity.nrrd"
# Computed original_glszm_GrayLevelNonUniformityNormalized, stored as "./dataset/glszm/kernel5-radius5/tumor/BraTS2021_00151/original_glszm_GrayLevelNonUniformityNormalized.nrrd"
# Computed original_glszm_GrayLevelVariance, stored as "./dataset/glszm/kernel5-radius5/tumor/BraTS2021_00151/original_glszm_GrayLevelVariance.nrrd"
# Computed original_glszm_HighGrayLevelZoneEmphasis, stored as "./dataset/glszm/kernel5-radius5/tumor/BraTS2021_00151/original_glszm_HighGrayLevelZoneEmphasis.nrrd"
# Computed original_glszm_LargeAreaEmphasis, stored as "./dataset/glszm/kernel5-radius5/tumor/BraTS2021_00151/original_glszm_LargeAreaEmphasis.nrrd"
# Computed original_glszm_LargeAreaHighGrayLevelEmphasis, stored as "./dataset/glszm/kernel5-radius5/tumor/BraTS2021_00151/original_glszm_LargeAreaHighGrayLevelEmphasis.nrrd"
# Computed original_glszm_LargeAreaLowGrayLevelEmphasis, stored as "./dataset/glszm/kernel5-radius5/tumor/BraTS2021_00151/original_glszm_LargeAreaLowGrayLevelEmphasis.nrrd"
# Computed original_glszm_LowGrayLevelZoneEmphasis, stored as "./dataset/glszm/kernel5-radius5/tumor/BraTS2021_00151/original_glszm_LowGrayLevelZoneEmphasis.nrrd"
# Computed original_glszm_SizeZoneNonUniformity, stored as "./dataset/glszm/kernel5-radius5/tumor/BraTS2021_00151/original_glszm_SizeZoneNonUniformity.nrrd"
# Computed original_glszm_SizeZoneNonUniformityNormalized, stored as "./dataset/glszm/kernel5-radius5/tumor/BraTS2021_00151/original_glszm_SizeZoneNonUniformityNormalized.nrrd"
# Computed original_glszm_SmallAreaEmphasis, stored as "./dataset/glszm/kernel5-radius5/tumor/BraTS2021_00151/original_glszm_SmallAreaEmphasis.nrrd"
# Computed original_glszm_SmallAreaHighGrayLevelEmphasis, stored as "./dataset/glszm/kernel5-radius5/tumor/BraTS2021_00151/original_glszm_SmallAreaHighGrayLevelEmphasis.nrrd"
# Computed original_glszm_SmallAreaLowGrayLevelEmphasis, stored as "./dataset/glszm/kernel5-radius5/tumor/BraTS2021_00151/original_glszm_SmallAreaLowGrayLevelEmphasis.nrrd"
# Computed original_glszm_ZoneEntropy, stored as "./dataset/glszm/kernel5-radius5/tumor/BraTS2021_00151/original_glszm_ZoneEntropy.nrrd"
# Computed original_glszm_ZonePercentage, stored as "./dataset/glszm/kernel5-radius5/tumor/BraTS2021_00151/original_glszm_ZonePercentage.nrrd"
# Computed original_glszm_ZoneVariance, stored as "./dataset/glszm/kernel5-radius5/tumor/BraTS2021_00151/original_glszm_ZoneVariance.nrrd"
# Starting BraTS2021_00152
# Computed original_glszm_GrayLevelNonUniformity, stored as "./dataset/glszm/kernel5-radius5/tumor/BraTS2021_00152/original_glszm_GrayLevelNonUniformity.nrrd"
# Computed original_glszm_GrayLevelNonUniformityNormalized, stored as "./dataset/glszm/kernel5-radius5/tumor/BraTS2021_00152/original_glszm_GrayLevelNonUniformityNormalized.nrrd"
# Computed original_glszm_GrayLevelVariance, stored as "./dataset/glszm/kernel5-radius5/tumor/BraTS2021_00152/original_glszm_GrayLevelVariance.nrrd"
# Computed original_glszm_HighGrayLevelZoneEmphasis, stored as "./dataset/glszm/kernel5-radius5/tumor/BraTS2021_00152/original_glszm_HighGrayLevelZoneEmphasis.nrrd"
# Computed original_glszm_LargeAreaEmphasis, stored as "./dataset/glszm/kernel5-radius5/tumor/BraTS2021_00152/original_glszm_LargeAreaEmphasis.nrrd"
# Computed original_glszm_LargeAreaHighGrayLevelEmphasis, stored as "./dataset/glszm/kernel5-radius5/tumor/BraTS2021_00152/original_glszm_LargeAreaHighGrayLevelEmphasis.nrrd"
# Computed original_glszm_LargeAreaLowGrayLevelEmphasis, stored as "./dataset/glszm/kernel5-radius5/tumor/BraTS2021_00152/original_glszm_LargeAreaLowGrayLevelEmphasis.nrrd"
# Computed original_glszm_LowGrayLevelZoneEmphasis, stored as "./dataset/glszm/kernel5-radius5/tumor/BraTS2021_00152/original_glszm_LowGrayLevelZoneEmphasis.nrrd"
# Computed original_glszm_SizeZoneNonUniformity, stored as "./dataset/glszm/kernel5-radius5/tumor/BraTS2021_00152/original_glszm_SizeZoneNonUniformity.nrrd"
# Computed original_glszm_SizeZoneNonUniformityNormalized, stored as "./dataset/glszm/kernel5-radius5/tumor/BraTS2021_00152/original_glszm_SizeZoneNonUniformityNormalized.nrrd"
# Computed original_glszm_SmallAreaEmphasis, stored as "./dataset/glszm/kernel5-radius5/tumor/BraTS2021_00152/original_glszm_SmallAreaEmphasis.nrrd"
# Computed original_glszm_SmallAreaHighGrayLevelEmphasis, stored as "./dataset/glszm/kernel5-radius5/tumor/BraTS2021_00152/original_glszm_SmallAreaHighGrayLevelEmphasis.nrrd"
# Computed original_glszm_SmallAreaLowGrayLevelEmphasis, stored as "./dataset/glszm/kernel5-radius5/tumor/BraTS2021_00152/original_glszm_SmallAreaLowGrayLevelEmphasis.nrrd"
# Computed original_glszm_ZoneEntropy, stored as "./dataset/glszm/kernel5-radius5/tumor/BraTS2021_00152/original_glszm_ZoneEntropy.nrrd"
# Computed original_glszm_ZonePercentage, stored as "./dataset/glszm/kernel5-radius5/tumor/BraTS2021_00152/original_glszm_ZonePercentage.nrrd"
# Computed original_glszm_ZoneVariance, stored as "./dataset/glszm/kernel5-radius5/tumor/BraTS2021_00152/original_glszm_ZoneVariance.nrrd"
# Starting BraTS2021_00154
# Computed original_glszm_GrayLevelNonUniformity, stored as "./dataset/glszm/kernel5-radius5/tumor/BraTS2021_00154/original_glszm_GrayLevelNonUniformity.nrrd"
# Computed original_glszm_GrayLevelNonUniformityNormalized, stored as "./dataset/glszm/kernel5-radius5/tumor/BraTS2021_00154/original_glszm_GrayLevelNonUniformityNormalized.nrrd"
# Computed original_glszm_GrayLevelVariance, stored as "./dataset/glszm/kernel5-radius5/tumor/BraTS2021_00154/original_glszm_GrayLevelVariance.nrrd"
# Computed original_glszm_HighGrayLevelZoneEmphasis, stored as "./dataset/glszm/kernel5-radius5/tumor/BraTS2021_00154/original_glszm_HighGrayLevelZoneEmphasis.nrrd"
# Computed original_glszm_LargeAreaEmphasis, stored as "./dataset/glszm/kernel5-radius5/tumor/BraTS2021_00154/original_glszm_LargeAreaEmphasis.nrrd"
# Computed original_glszm_LargeAreaHighGrayLevelEmphasis, stored as "./dataset/glszm/kernel5-radius5/tumor/BraTS2021_00154/original_glszm_LargeAreaHighGrayLevelEmphasis.nrrd"
# Computed original_glszm_LargeAreaLowGrayLevelEmphasis, stored as "./dataset/glszm/kernel5-radius5/tumor/BraTS2021_00154/original_glszm_LargeAreaLowGrayLevelEmphasis.nrrd"
# Computed original_glszm_LowGrayLevelZoneEmphasis, stored as "./dataset/glszm/kernel5-radius5/tumor/BraTS2021_00154/original_glszm_LowGrayLevelZoneEmphasis.nrrd"
# Computed original_glszm_SizeZoneNonUniformity, stored as "./dataset/glszm/kernel5-radius5/tumor/BraTS2021_00154/original_glszm_SizeZoneNonUniformity.nrrd"
# Computed original_glszm_SizeZoneNonUniformityNormalized, stored as "./dataset/glszm/kernel5-radius5/tumor/BraTS2021_00154/original_glszm_SizeZoneNonUniformityNormalized.nrrd"
# Computed original_glszm_SmallAreaEmphasis, stored as "./dataset/glszm/kernel5-radius5/tumor/BraTS2021_00154/original_glszm_SmallAreaEmphasis.nrrd"
# Computed original_glszm_SmallAreaHighGrayLevelEmphasis, stored as "./dataset/glszm/kernel5-radius5/tumor/BraTS2021_00154/original_glszm_SmallAreaHighGrayLevelEmphasis.nrrd"
# Computed original_glszm_SmallAreaLowGrayLevelEmphasis, stored as "./dataset/glszm/kernel5-radius5/tumor/BraTS2021_00154/original_glszm_SmallAreaLowGrayLevelEmphasis.nrrd"
# Computed original_glszm_ZoneEntropy, stored as "./dataset/glszm/kernel5-radius5/tumor/BraTS2021_00154/original_glszm_ZoneEntropy.nrrd"
# Computed original_glszm_ZonePercentage, stored as "./dataset/glszm/kernel5-radius5/tumor/BraTS2021_00154/original_glszm_ZonePercentage.nrrd"
# Computed original_glszm_ZoneVariance, stored as "./dataset/glszm/kernel5-radius5/tumor/BraTS2021_00154/original_glszm_ZoneVariance.nrrd"
# Starting BraTS2021_00155
# Computed original_glszm_GrayLevelNonUniformity, stored as "./dataset/glszm/kernel5-radius5/tumor/BraTS2021_00155/original_glszm_GrayLevelNonUniformity.nrrd"
# Computed original_glszm_GrayLevelNonUniformityNormalized, stored as "./dataset/glszm/kernel5-radius5/tumor/BraTS2021_00155/original_glszm_GrayLevelNonUniformityNormalized.nrrd"
# Computed original_glszm_GrayLevelVariance, stored as "./dataset/glszm/kernel5-radius5/tumor/BraTS2021_00155/original_glszm_GrayLevelVariance.nrrd"
# Computed original_glszm_HighGrayLevelZoneEmphasis, stored as "./dataset/glszm/kernel5-radius5/tumor/BraTS2021_00155/original_glszm_HighGrayLevelZoneEmphasis.nrrd"
# Computed original_glszm_LargeAreaEmphasis, stored as "./dataset/glszm/kernel5-radius5/tumor/BraTS2021_00155/original_glszm_LargeAreaEmphasis.nrrd"
# Computed original_glszm_LargeAreaHighGrayLevelEmphasis, stored as "./dataset/glszm/kernel5-radius5/tumor/BraTS2021_00155/original_glszm_LargeAreaHighGrayLevelEmphasis.nrrd"
# Computed original_glszm_LargeAreaLowGrayLevelEmphasis, stored as "./dataset/glszm/kernel5-radius5/tumor/BraTS2021_00155/original_glszm_LargeAreaLowGrayLevelEmphasis.nrrd"
# Computed original_glszm_LowGrayLevelZoneEmphasis, stored as "./dataset/glszm/kernel5-radius5/tumor/BraTS2021_00155/original_glszm_LowGrayLevelZoneEmphasis.nrrd"
# Computed original_glszm_SizeZoneNonUniformity, stored as "./dataset/glszm/kernel5-radius5/tumor/BraTS2021_00155/original_glszm_SizeZoneNonUniformity.nrrd"
# Computed original_glszm_SizeZoneNonUniformityNormalized, stored as "./dataset/glszm/kernel5-radius5/tumor/BraTS2021_00155/original_glszm_SizeZoneNonUniformityNormalized.nrrd"
# Computed original_glszm_SmallAreaEmphasis, stored as "./dataset/glszm/kernel5-radius5/tumor/BraTS2021_00155/original_glszm_SmallAreaEmphasis.nrrd"
# Computed original_glszm_SmallAreaHighGrayLevelEmphasis, stored as "./dataset/glszm/kernel5-radius5/tumor/BraTS2021_00155/original_glszm_SmallAreaHighGrayLevelEmphasis.nrrd"
# Computed original_glszm_SmallAreaLowGrayLevelEmphasis, stored as "./dataset/glszm/kernel5-radius5/tumor/BraTS2021_00155/original_glszm_SmallAreaLowGrayLevelEmphasis.nrrd"
# Computed original_glszm_ZoneEntropy, stored as "./dataset/glszm/kernel5-radius5/tumor/BraTS2021_00155/original_glszm_ZoneEntropy.nrrd"
# Computed original_glszm_ZonePercentage, stored as "./dataset/glszm/kernel5-radius5/tumor/BraTS2021_00155/original_glszm_ZonePercentage.nrrd"
# Computed original_glszm_ZoneVariance, stored as "./dataset/glszm/kernel5-radius5/tumor/BraTS2021_00155/original_glszm_ZoneVariance.nrrd"
# Starting BraTS2021_00156
# Computed original_glszm_GrayLevelNonUniformity, stored as "./dataset/glszm/kernel5-radius5/tumor/BraTS2021_00156/original_glszm_GrayLevelNonUniformity.nrrd"
# Computed original_glszm_GrayLevelNonUniformityNormalized, stored as "./dataset/glszm/kernel5-radius5/tumor/BraTS2021_00156/original_glszm_GrayLevelNonUniformityNormalized.nrrd"
# Computed original_glszm_GrayLevelVariance, stored as "./dataset/glszm/kernel5-radius5/tumor/BraTS2021_00156/original_glszm_GrayLevelVariance.nrrd"
# Computed original_glszm_HighGrayLevelZoneEmphasis, stored as "./dataset/glszm/kernel5-radius5/tumor/BraTS2021_00156/original_glszm_HighGrayLevelZoneEmphasis.nrrd"
# Computed original_glszm_LargeAreaEmphasis, stored as "./dataset/glszm/kernel5-radius5/tumor/BraTS2021_00156/original_glszm_LargeAreaEmphasis.nrrd"
# Computed original_glszm_LargeAreaHighGrayLevelEmphasis, stored as "./dataset/glszm/kernel5-radius5/tumor/BraTS2021_00156/original_glszm_LargeAreaHighGrayLevelEmphasis.nrrd"
# Computed original_glszm_LargeAreaLowGrayLevelEmphasis, stored as "./dataset/glszm/kernel5-radius5/tumor/BraTS2021_00156/original_glszm_LargeAreaLowGrayLevelEmphasis.nrrd"
# Computed original_glszm_LowGrayLevelZoneEmphasis, stored as "./dataset/glszm/kernel5-radius5/tumor/BraTS2021_00156/original_glszm_LowGrayLevelZoneEmphasis.nrrd"
# Computed original_glszm_SizeZoneNonUniformity, stored as "./dataset/glszm/kernel5-radius5/tumor/BraTS2021_00156/original_glszm_SizeZoneNonUniformity.nrrd"
# Computed original_glszm_SizeZoneNonUniformityNormalized, stored as "./dataset/glszm/kernel5-radius5/tumor/BraTS2021_00156/original_glszm_SizeZoneNonUniformityNormalized.nrrd"
# Computed original_glszm_SmallAreaEmphasis, stored as "./dataset/glszm/kernel5-radius5/tumor/BraTS2021_00156/original_glszm_SmallAreaEmphasis.nrrd"
# Computed original_glszm_SmallAreaHighGrayLevelEmphasis, stored as "./dataset/glszm/kernel5-radius5/tumor/BraTS2021_00156/original_glszm_SmallAreaHighGrayLevelEmphasis.nrrd"
# Computed original_glszm_SmallAreaLowGrayLevelEmphasis, stored as "./dataset/glszm/kernel5-radius5/tumor/BraTS2021_00156/original_glszm_SmallAreaLowGrayLevelEmphasis.nrrd"
# Computed original_glszm_ZoneEntropy, stored as "./dataset/glszm/kernel5-radius5/tumor/BraTS2021_00156/original_glszm_ZoneEntropy.nrrd"
# Computed original_glszm_ZonePercentage, stored as "./dataset/glszm/kernel5-radius5/tumor/BraTS2021_00156/original_glszm_ZonePercentage.nrrd"
# Computed original_glszm_ZoneVariance, stored as "./dataset/glszm/kernel5-radius5/tumor/BraTS2021_00156/original_glszm_ZoneVariance.nrrd"
# Starting BraTS2021_00157
# Computed original_glszm_GrayLevelNonUniformity, stored as "./dataset/glszm/kernel5-radius5/tumor/BraTS2021_00157/original_glszm_GrayLevelNonUniformity.nrrd"
# Computed original_glszm_GrayLevelNonUniformityNormalized, stored as "./dataset/glszm/kernel5-radius5/tumor/BraTS2021_00157/original_glszm_GrayLevelNonUniformityNormalized.nrrd"
# Computed original_glszm_GrayLevelVariance, stored as "./dataset/glszm/kernel5-radius5/tumor/BraTS2021_00157/original_glszm_GrayLevelVariance.nrrd"
# Computed original_glszm_HighGrayLevelZoneEmphasis, stored as "./dataset/glszm/kernel5-radius5/tumor/BraTS2021_00157/original_glszm_HighGrayLevelZoneEmphasis.nrrd"
# Computed original_glszm_LargeAreaEmphasis, stored as "./dataset/glszm/kernel5-radius5/tumor/BraTS2021_00157/original_glszm_LargeAreaEmphasis.nrrd"
# Computed original_glszm_LargeAreaHighGrayLevelEmphasis, stored as "./dataset/glszm/kernel5-radius5/tumor/BraTS2021_00157/original_glszm_LargeAreaHighGrayLevelEmphasis.nrrd"
# Computed original_glszm_LargeAreaLowGrayLevelEmphasis, stored as "./dataset/glszm/kernel5-radius5/tumor/BraTS2021_00157/original_glszm_LargeAreaLowGrayLevelEmphasis.nrrd"
# Computed original_glszm_LowGrayLevelZoneEmphasis, stored as "./dataset/glszm/kernel5-radius5/tumor/BraTS2021_00157/original_glszm_LowGrayLevelZoneEmphasis.nrrd"
# Computed original_glszm_SizeZoneNonUniformity, stored as "./dataset/glszm/kernel5-radius5/tumor/BraTS2021_00157/original_glszm_SizeZoneNonUniformity.nrrd"
# Computed original_glszm_SizeZoneNonUniformityNormalized, stored as "./dataset/glszm/kernel5-radius5/tumor/BraTS2021_00157/original_glszm_SizeZoneNonUniformityNormalized.nrrd"
# Computed original_glszm_SmallAreaEmphasis, stored as "./dataset/glszm/kernel5-radius5/tumor/BraTS2021_00157/original_glszm_SmallAreaEmphasis.nrrd"
# Computed original_glszm_SmallAreaHighGrayLevelEmphasis, stored as "./dataset/glszm/kernel5-radius5/tumor/BraTS2021_00157/original_glszm_SmallAreaHighGrayLevelEmphasis.nrrd"
# Computed original_glszm_SmallAreaLowGrayLevelEmphasis, stored as "./dataset/glszm/kernel5-radius5/tumor/BraTS2021_00157/original_glszm_SmallAreaLowGrayLevelEmphasis.nrrd"
# Computed original_glszm_ZoneEntropy, stored as "./dataset/glszm/kernel5-radius5/tumor/BraTS2021_00157/original_glszm_ZoneEntropy.nrrd"
# Computed original_glszm_ZonePercentage, stored as "./dataset/glszm/kernel5-radius5/tumor/BraTS2021_00157/original_glszm_ZonePercentage.nrrd"
# Computed original_glszm_ZoneVariance, stored as "./dataset/glszm/kernel5-radius5/tumor/BraTS2021_00157/original_glszm_ZoneVariance.nrrd"
# Starting BraTS2021_00158
# Computed original_glszm_GrayLevelNonUniformity, stored as "./dataset/glszm/kernel5-radius5/tumor/BraTS2021_00158/original_glszm_GrayLevelNonUniformity.nrrd"
# Computed original_glszm_GrayLevelNonUniformityNormalized, stored as "./dataset/glszm/kernel5-radius5/tumor/BraTS2021_00158/original_glszm_GrayLevelNonUniformityNormalized.nrrd"
# Computed original_glszm_GrayLevelVariance, stored as "./dataset/glszm/kernel5-radius5/tumor/BraTS2021_00158/original_glszm_GrayLevelVariance.nrrd"
# Computed original_glszm_HighGrayLevelZoneEmphasis, stored as "./dataset/glszm/kernel5-radius5/tumor/BraTS2021_00158/original_glszm_HighGrayLevelZoneEmphasis.nrrd"
# Computed original_glszm_LargeAreaEmphasis, stored as "./dataset/glszm/kernel5-radius5/tumor/BraTS2021_00158/original_glszm_LargeAreaEmphasis.nrrd"
# Computed original_glszm_LargeAreaHighGrayLevelEmphasis, stored as "./dataset/glszm/kernel5-radius5/tumor/BraTS2021_00158/original_glszm_LargeAreaHighGrayLevelEmphasis.nrrd"
# Computed original_glszm_LargeAreaLowGrayLevelEmphasis, stored as "./dataset/glszm/kernel5-radius5/tumor/BraTS2021_00158/original_glszm_LargeAreaLowGrayLevelEmphasis.nrrd"
# Computed original_glszm_LowGrayLevelZoneEmphasis, stored as "./dataset/glszm/kernel5-radius5/tumor/BraTS2021_00158/original_glszm_LowGrayLevelZoneEmphasis.nrrd"
# Computed original_glszm_SizeZoneNonUniformity, stored as "./dataset/glszm/kernel5-radius5/tumor/BraTS2021_00158/original_glszm_SizeZoneNonUniformity.nrrd"
# Computed original_glszm_SizeZoneNonUniformityNormalized, stored as "./dataset/glszm/kernel5-radius5/tumor/BraTS2021_00158/original_glszm_SizeZoneNonUniformityNormalized.nrrd"
# Computed original_glszm_SmallAreaEmphasis, stored as "./dataset/glszm/kernel5-radius5/tumor/BraTS2021_00158/original_glszm_SmallAreaEmphasis.nrrd"
# Computed original_glszm_SmallAreaHighGrayLevelEmphasis, stored as "./dataset/glszm/kernel5-radius5/tumor/BraTS2021_00158/original_glszm_SmallAreaHighGrayLevelEmphasis.nrrd"
# Computed original_glszm_SmallAreaLowGrayLevelEmphasis, stored as "./dataset/glszm/kernel5-radius5/tumor/BraTS2021_00158/original_glszm_SmallAreaLowGrayLevelEmphasis.nrrd"
# Computed original_glszm_ZoneEntropy, stored as "./dataset/glszm/kernel5-radius5/tumor/BraTS2021_00158/original_glszm_ZoneEntropy.nrrd"
# Computed original_glszm_ZonePercentage, stored as "./dataset/glszm/kernel5-radius5/tumor/BraTS2021_00158/original_glszm_ZonePercentage.nrrd"
# Computed original_glszm_ZoneVariance, stored as "./dataset/glszm/kernel5-radius5/tumor/BraTS2021_00158/original_glszm_ZoneVariance.nrrd"
# Starting BraTS2021_00159
# Computed original_glszm_GrayLevelNonUniformity, stored as "./dataset/glszm/kernel5-radius5/tumor/BraTS2021_00159/original_glszm_GrayLevelNonUniformity.nrrd"
# Computed original_glszm_GrayLevelNonUniformityNormalized, stored as "./dataset/glszm/kernel5-radius5/tumor/BraTS2021_00159/original_glszm_GrayLevelNonUniformityNormalized.nrrd"
# Computed original_glszm_GrayLevelVariance, stored as "./dataset/glszm/kernel5-radius5/tumor/BraTS2021_00159/original_glszm_GrayLevelVariance.nrrd"
# Computed original_glszm_HighGrayLevelZoneEmphasis, stored as "./dataset/glszm/kernel5-radius5/tumor/BraTS2021_00159/original_glszm_HighGrayLevelZoneEmphasis.nrrd"
# Computed original_glszm_LargeAreaEmphasis, stored as "./dataset/glszm/kernel5-radius5/tumor/BraTS2021_00159/original_glszm_LargeAreaEmphasis.nrrd"
# Computed original_glszm_LargeAreaHighGrayLevelEmphasis, stored as "./dataset/glszm/kernel5-radius5/tumor/BraTS2021_00159/original_glszm_LargeAreaHighGrayLevelEmphasis.nrrd"
# Computed original_glszm_LargeAreaLowGrayLevelEmphasis, stored as "./dataset/glszm/kernel5-radius5/tumor/BraTS2021_00159/original_glszm_LargeAreaLowGrayLevelEmphasis.nrrd"
# Computed original_glszm_LowGrayLevelZoneEmphasis, stored as "./dataset/glszm/kernel5-radius5/tumor/BraTS2021_00159/original_glszm_LowGrayLevelZoneEmphasis.nrrd"
# Computed original_glszm_SizeZoneNonUniformity, stored as "./dataset/glszm/kernel5-radius5/tumor/BraTS2021_00159/original_glszm_SizeZoneNonUniformity.nrrd"
# Computed original_glszm_SizeZoneNonUniformityNormalized, stored as "./dataset/glszm/kernel5-radius5/tumor/BraTS2021_00159/original_glszm_SizeZoneNonUniformityNormalized.nrrd"
# Computed original_glszm_SmallAreaEmphasis, stored as "./dataset/glszm/kernel5-radius5/tumor/BraTS2021_00159/original_glszm_SmallAreaEmphasis.nrrd"
# Computed original_glszm_SmallAreaHighGrayLevelEmphasis, stored as "./dataset/glszm/kernel5-radius5/tumor/BraTS2021_00159/original_glszm_SmallAreaHighGrayLevelEmphasis.nrrd"
# Computed original_glszm_SmallAreaLowGrayLevelEmphasis, stored as "./dataset/glszm/kernel5-radius5/tumor/BraTS2021_00159/original_glszm_SmallAreaLowGrayLevelEmphasis.nrrd"
# Computed original_glszm_ZoneEntropy, stored as "./dataset/glszm/kernel5-radius5/tumor/BraTS2021_00159/original_glszm_ZoneEntropy.nrrd"
# Computed original_glszm_ZonePercentage, stored as "./dataset/glszm/kernel5-radius5/tumor/BraTS2021_00159/original_glszm_ZonePercentage.nrrd"
# Computed original_glszm_ZoneVariance, stored as "./dataset/glszm/kernel5-radius5/tumor/BraTS2021_00159/original_glszm_ZoneVariance.nrrd"
# Starting BraTS2021_00160
# Computed original_glszm_GrayLevelNonUniformity, stored as "./dataset/glszm/kernel5-radius5/tumor/BraTS2021_00160/original_glszm_GrayLevelNonUniformity.nrrd"
# Computed original_glszm_GrayLevelNonUniformityNormalized, stored as "./dataset/glszm/kernel5-radius5/tumor/BraTS2021_00160/original_glszm_GrayLevelNonUniformityNormalized.nrrd"
# Computed original_glszm_GrayLevelVariance, stored as "./dataset/glszm/kernel5-radius5/tumor/BraTS2021_00160/original_glszm_GrayLevelVariance.nrrd"
# Computed original_glszm_HighGrayLevelZoneEmphasis, stored as "./dataset/glszm/kernel5-radius5/tumor/BraTS2021_00160/original_glszm_HighGrayLevelZoneEmphasis.nrrd"
# Computed original_glszm_LargeAreaEmphasis, stored as "./dataset/glszm/kernel5-radius5/tumor/BraTS2021_00160/original_glszm_LargeAreaEmphasis.nrrd"
# Computed original_glszm_LargeAreaHighGrayLevelEmphasis, stored as "./dataset/glszm/kernel5-radius5/tumor/BraTS2021_00160/original_glszm_LargeAreaHighGrayLevelEmphasis.nrrd"
# Computed original_glszm_LargeAreaLowGrayLevelEmphasis, stored as "./dataset/glszm/kernel5-radius5/tumor/BraTS2021_00160/original_glszm_LargeAreaLowGrayLevelEmphasis.nrrd"
# Computed original_glszm_LowGrayLevelZoneEmphasis, stored as "./dataset/glszm/kernel5-radius5/tumor/BraTS2021_00160/original_glszm_LowGrayLevelZoneEmphasis.nrrd"
# Computed original_glszm_SizeZoneNonUniformity, stored as "./dataset/glszm/kernel5-radius5/tumor/BraTS2021_00160/original_glszm_SizeZoneNonUniformity.nrrd"
# Computed original_glszm_SizeZoneNonUniformityNormalized, stored as "./dataset/glszm/kernel5-radius5/tumor/BraTS2021_00160/original_glszm_SizeZoneNonUniformityNormalized.nrrd"
# Computed original_glszm_SmallAreaEmphasis, stored as "./dataset/glszm/kernel5-radius5/tumor/BraTS2021_00160/original_glszm_SmallAreaEmphasis.nrrd"
# Computed original_glszm_SmallAreaHighGrayLevelEmphasis, stored as "./dataset/glszm/kernel5-radius5/tumor/BraTS2021_00160/original_glszm_SmallAreaHighGrayLevelEmphasis.nrrd"
# Computed original_glszm_SmallAreaLowGrayLevelEmphasis, stored as "./dataset/glszm/kernel5-radius5/tumor/BraTS2021_00160/original_glszm_SmallAreaLowGrayLevelEmphasis.nrrd"
# Computed original_glszm_ZoneEntropy, stored as "./dataset/glszm/kernel5-radius5/tumor/BraTS2021_00160/original_glszm_ZoneEntropy.nrrd"
# Computed original_glszm_ZonePercentage, stored as "./dataset/glszm/kernel5-radius5/tumor/BraTS2021_00160/original_glszm_ZonePercentage.nrrd"
# Computed original_glszm_ZoneVariance, stored as "./dataset/glszm/kernel5-radius5/tumor/BraTS2021_00160/original_glszm_ZoneVariance.nrrd"
# Starting BraTS2021_00162
# Computed original_glszm_GrayLevelNonUniformity, stored as "./dataset/glszm/kernel5-radius5/tumor/BraTS2021_00162/original_glszm_GrayLevelNonUniformity.nrrd"
# Computed original_glszm_GrayLevelNonUniformityNormalized, stored as "./dataset/glszm/kernel5-radius5/tumor/BraTS2021_00162/original_glszm_GrayLevelNonUniformityNormalized.nrrd"
# Computed original_glszm_GrayLevelVariance, stored as "./dataset/glszm/kernel5-radius5/tumor/BraTS2021_00162/original_glszm_GrayLevelVariance.nrrd"
# Computed original_glszm_HighGrayLevelZoneEmphasis, stored as "./dataset/glszm/kernel5-radius5/tumor/BraTS2021_00162/original_glszm_HighGrayLevelZoneEmphasis.nrrd"
# Computed original_glszm_LargeAreaEmphasis, stored as "./dataset/glszm/kernel5-radius5/tumor/BraTS2021_00162/original_glszm_LargeAreaEmphasis.nrrd"
# Computed original_glszm_LargeAreaHighGrayLevelEmphasis, stored as "./dataset/glszm/kernel5-radius5/tumor/BraTS2021_00162/original_glszm_LargeAreaHighGrayLevelEmphasis.nrrd"
# Computed original_glszm_LargeAreaLowGrayLevelEmphasis, stored as "./dataset/glszm/kernel5-radius5/tumor/BraTS2021_00162/original_glszm_LargeAreaLowGrayLevelEmphasis.nrrd"
# Computed original_glszm_LowGrayLevelZoneEmphasis, stored as "./dataset/glszm/kernel5-radius5/tumor/BraTS2021_00162/original_glszm_LowGrayLevelZoneEmphasis.nrrd"
# Computed original_glszm_SizeZoneNonUniformity, stored as "./dataset/glszm/kernel5-radius5/tumor/BraTS2021_00162/original_glszm_SizeZoneNonUniformity.nrrd"
# Computed original_glszm_SizeZoneNonUniformityNormalized, stored as "./dataset/glszm/kernel5-radius5/tumor/BraTS2021_00162/original_glszm_SizeZoneNonUniformityNormalized.nrrd"
# Computed original_glszm_SmallAreaEmphasis, stored as "./dataset/glszm/kernel5-radius5/tumor/BraTS2021_00162/original_glszm_SmallAreaEmphasis.nrrd"
# Computed original_glszm_SmallAreaHighGrayLevelEmphasis, stored as "./dataset/glszm/kernel5-radius5/tumor/BraTS2021_00162/original_glszm_SmallAreaHighGrayLevelEmphasis.nrrd"
# ...
# Computed original_glszm_SmallAreaLowGrayLevelEmphasis, stored as "./dataset/glszm/kernel5-radius5/tumor/BraTS2021_00275/original_glszm_SmallAreaLowGrayLevelEmphasis.nrrd"
# Computed original_glszm_ZoneEntropy, stored as "./dataset/glszm/kernel5-radius5/tumor/BraTS2021_00275/original_glszm_ZoneEntropy.nrrd"
# Computed original_glszm_ZonePercentage, stored as "./dataset/glszm/kernel5-radius5/tumor/BraTS2021_00275/original_glszm_ZonePercentage.nrrd"
# Computed original_glszm_ZoneVariance, stored as "./dataset/glszm/kernel5-radius5/tumor/BraTS2021_00275/original_glszm_ZoneVariance.nrrd"
# Starting BraTS2021_00280
# Computed original_glszm_GrayLevelNonUniformity, stored as "./dataset/glszm/kernel5-radius5/tumor/BraTS2021_00280/original_glszm_GrayLevelNonUniformity.nrrd"
# Computed original_glszm_GrayLevelNonUniformityNormalized, stored as "./dataset/glszm/kernel5-radius5/tumor/BraTS2021_00280/original_glszm_GrayLevelNonUniformityNormalized.nrrd"
# Computed original_glszm_GrayLevelVariance, stored as "./dataset/glszm/kernel5-radius5/tumor/BraTS2021_00280/original_glszm_GrayLevelVariance.nrrd"
# Computed original_glszm_HighGrayLevelZoneEmphasis, stored as "./dataset/glszm/kernel5-radius5/tumor/BraTS2021_00280/original_glszm_HighGrayLevelZoneEmphasis.nrrd"
# Computed original_glszm_LargeAreaEmphasis, stored as "./dataset/glszm/kernel5-radius5/tumor/BraTS2021_00280/original_glszm_LargeAreaEmphasis.nrrd"
# Computed original_glszm_LargeAreaHighGrayLevelEmphasis, stored as "./dataset/glszm/kernel5-radius5/tumor/BraTS2021_00280/original_glszm_LargeAreaHighGrayLevelEmphasis.nrrd"
# Computed original_glszm_LargeAreaLowGrayLevelEmphasis, stored as "./dataset/glszm/kernel5-radius5/tumor/BraTS2021_00280/original_glszm_LargeAreaLowGrayLevelEmphasis.nrrd"
# Computed original_glszm_LowGrayLevelZoneEmphasis, stored as "./dataset/glszm/kernel5-radius5/tumor/BraTS2021_00280/original_glszm_LowGrayLevelZoneEmphasis.nrrd"
# Computed original_glszm_SizeZoneNonUniformity, stored as "./dataset/glszm/kernel5-radius5/tumor/BraTS2021_00280/original_glszm_SizeZoneNonUniformity.nrrd"
# Computed original_glszm_SizeZoneNonUniformityNormalized, stored as "./dataset/glszm/kernel5-radius5/tumor/BraTS2021_00280/original_glszm_SizeZoneNonUniformityNormalized.nrrd"
# Computed original_glszm_SmallAreaEmphasis, stored as "./dataset/glszm/kernel5-radius5/tumor/BraTS2021_00280/original_glszm_SmallAreaEmphasis.nrrd"
# Computed original_glszm_SmallAreaHighGrayLevelEmphasis, stored as "./dataset/glszm/kernel5-radius5/tumor/BraTS2021_00280/original_glszm_SmallAreaHighGrayLevelEmphasis.nrrd"
# Computed original_glszm_SmallAreaLowGrayLevelEmphasis, stored as "./dataset/glszm/kernel5-radius5/tumor/BraTS2021_00280/original_glszm_SmallAreaLowGrayLevelEmphasis.nrrd"
# Computed original_glszm_ZoneEntropy, stored as "./dataset/glszm/kernel5-radius5/tumor/BraTS2021_00280/original_glszm_ZoneEntropy.nrrd"
# Computed original_glszm_ZonePercentage, stored as "./dataset/glszm/kernel5-radius5/tumor/BraTS2021_00280/original_glszm_ZonePercentage.nrrd"
# Computed original_glszm_ZoneVariance, stored as "./dataset/glszm/kernel5-radius5/tumor/BraTS2021_00280/original_glszm_ZoneVariance.nrrd"
# Starting BraTS2021_00281
# Computed original_glszm_GrayLevelNonUniformity, stored as "./dataset/glszm/kernel5-radius5/tumor/BraTS2021_00281/original_glszm_GrayLevelNonUniformity.nrrd"
# Computed original_glszm_GrayLevelNonUniformityNormalized, stored as "./dataset/glszm/kernel5-radius5/tumor/BraTS2021_00281/original_glszm_GrayLevelNonUniformityNormalized.nrrd"
# Computed original_glszm_GrayLevelVariance, stored as "./dataset/glszm/kernel5-radius5/tumor/BraTS2021_00281/original_glszm_GrayLevelVariance.nrrd"
# Computed original_glszm_HighGrayLevelZoneEmphasis, stored as "./dataset/glszm/kernel5-radius5/tumor/BraTS2021_00281/original_glszm_HighGrayLevelZoneEmphasis.nrrd"
# Computed original_glszm_LargeAreaEmphasis, stored as "./dataset/glszm/kernel5-radius5/tumor/BraTS2021_00281/original_glszm_LargeAreaEmphasis.nrrd"
# Computed original_glszm_LargeAreaHighGrayLevelEmphasis, stored as "./dataset/glszm/kernel5-radius5/tumor/BraTS2021_00281/original_glszm_LargeAreaHighGrayLevelEmphasis.nrrd"
# Computed original_glszm_LargeAreaLowGrayLevelEmphasis, stored as "./dataset/glszm/kernel5-radius5/tumor/BraTS2021_00281/original_glszm_LargeAreaLowGrayLevelEmphasis.nrrd"
# Computed original_glszm_LowGrayLevelZoneEmphasis, stored as "./dataset/glszm/kernel5-radius5/tumor/BraTS2021_00281/original_glszm_LowGrayLevelZoneEmphasis.nrrd"
# Computed original_glszm_SizeZoneNonUniformity, stored as "./dataset/glszm/kernel5-radius5/tumor/BraTS2021_00281/original_glszm_SizeZoneNonUniformity.nrrd"
# Computed original_glszm_SizeZoneNonUniformityNormalized, stored as "./dataset/glszm/kernel5-radius5/tumor/BraTS2021_00281/original_glszm_SizeZoneNonUniformityNormalized.nrrd"
# Computed original_glszm_SmallAreaEmphasis, stored as "./dataset/glszm/kernel5-radius5/tumor/BraTS2021_00281/original_glszm_SmallAreaEmphasis.nrrd"
# Computed original_glszm_SmallAreaHighGrayLevelEmphasis, stored as "./dataset/glszm/kernel5-radius5/tumor/BraTS2021_00281/original_glszm_SmallAreaHighGrayLevelEmphasis.nrrd"
# Computed original_glszm_SmallAreaLowGrayLevelEmphasis, stored as "./dataset/glszm/kernel5-radius5/tumor/BraTS2021_00281/original_glszm_SmallAreaLowGrayLevelEmphasis.nrrd"
# Computed original_glszm_ZoneEntropy, stored as "./dataset/glszm/kernel5-radius5/tumor/BraTS2021_00281/original_glszm_ZoneEntropy.nrrd"
# Computed original_glszm_ZonePercentage, stored as "./dataset/glszm/kernel5-radius5/tumor/BraTS2021_00281/original_glszm_ZonePercentage.nrrd"
# Computed original_glszm_ZoneVariance, stored as "./dataset/glszm/kernel5-radius5/tumor/BraTS2021_00281/original_glszm_ZoneVariance.nrrd"
# Starting BraTS2021_00282
# Computed original_glszm_GrayLevelNonUniformity, stored as "./dataset/glszm/kernel5-radius5/tumor/BraTS2021_00282/original_glszm_GrayLevelNonUniformity.nrrd"
# Computed original_glszm_GrayLevelNonUniformityNormalized, stored as "./dataset/glszm/kernel5-radius5/tumor/BraTS2021_00282/original_glszm_GrayLevelNonUniformityNormalized.nrrd"
# Computed original_glszm_GrayLevelVariance, stored as "./dataset/glszm/kernel5-radius5/tumor/BraTS2021_00282/original_glszm_GrayLevelVariance.nrrd"
# Computed original_glszm_HighGrayLevelZoneEmphasis, stored as "./dataset/glszm/kernel5-radius5/tumor/BraTS2021_00282/original_glszm_HighGrayLevelZoneEmphasis.nrrd"
# Computed original_glszm_LargeAreaEmphasis, stored as "./dataset/glszm/kernel5-radius5/tumor/BraTS2021_00282/original_glszm_LargeAreaEmphasis.nrrd"
# Computed original_glszm_LargeAreaHighGrayLevelEmphasis, stored as "./dataset/glszm/kernel5-radius5/tumor/BraTS2021_00282/original_glszm_LargeAreaHighGrayLevelEmphasis.nrrd"
# Computed original_glszm_LargeAreaLowGrayLevelEmphasis, stored as "./dataset/glszm/kernel5-radius5/tumor/BraTS2021_00282/original_glszm_LargeAreaLowGrayLevelEmphasis.nrrd"
# Computed original_glszm_LowGrayLevelZoneEmphasis, stored as "./dataset/glszm/kernel5-radius5/tumor/BraTS2021_00282/original_glszm_LowGrayLevelZoneEmphasis.nrrd"
# Computed original_glszm_SizeZoneNonUniformity, stored as "./dataset/glszm/kernel5-radius5/tumor/BraTS2021_00282/original_glszm_SizeZoneNonUniformity.nrrd"
# Computed original_glszm_SizeZoneNonUniformityNormalized, stored as "./dataset/glszm/kernel5-radius5/tumor/BraTS2021_00282/original_glszm_SizeZoneNonUniformityNormalized.nrrd"
# Computed original_glszm_SmallAreaEmphasis, stored as "./dataset/glszm/kernel5-radius5/tumor/BraTS2021_00282/original_glszm_SmallAreaEmphasis.nrrd"
# Computed original_glszm_SmallAreaHighGrayLevelEmphasis, stored as "./dataset/glszm/kernel5-radius5/tumor/BraTS2021_00282/original_glszm_SmallAreaHighGrayLevelEmphasis.nrrd"
# Computed original_glszm_SmallAreaLowGrayLevelEmphasis, stored as "./dataset/glszm/kernel5-radius5/tumor/BraTS2021_00282/original_glszm_SmallAreaLowGrayLevelEmphasis.nrrd"
# Computed original_glszm_ZoneEntropy, stored as "./dataset/glszm/kernel5-radius5/tumor/BraTS2021_00282/original_glszm_ZoneEntropy.nrrd"
# Computed original_glszm_ZonePercentage, stored as "./dataset/glszm/kernel5-radius5/tumor/BraTS2021_00282/original_glszm_ZonePercentage.nrrd"
# Computed original_glszm_ZoneVariance, stored as "./dataset/glszm/kernel5-radius5/tumor/BraTS2021_00282/original_glszm_ZoneVariance.nrrd"
# Starting BraTS2021_00283
# Computed original_glszm_GrayLevelNonUniformity, stored as "./dataset/glszm/kernel5-radius5/tumor/BraTS2021_00283/original_glszm_GrayLevelNonUniformity.nrrd"
# Computed original_glszm_GrayLevelNonUniformityNormalized, stored as "./dataset/glszm/kernel5-radius5/tumor/BraTS2021_00283/original_glszm_GrayLevelNonUniformityNormalized.nrrd"
# Computed original_glszm_GrayLevelVariance, stored as "./dataset/glszm/kernel5-radius5/tumor/BraTS2021_00283/original_glszm_GrayLevelVariance.nrrd"
# Computed original_glszm_HighGrayLevelZoneEmphasis, stored as "./dataset/glszm/kernel5-radius5/tumor/BraTS2021_00283/original_glszm_HighGrayLevelZoneEmphasis.nrrd"
# Computed original_glszm_LargeAreaEmphasis, stored as "./dataset/glszm/kernel5-radius5/tumor/BraTS2021_00283/original_glszm_LargeAreaEmphasis.nrrd"
# Computed original_glszm_LargeAreaHighGrayLevelEmphasis, stored as "./dataset/glszm/kernel5-radius5/tumor/BraTS2021_00283/original_glszm_LargeAreaHighGrayLevelEmphasis.nrrd"
# Computed original_glszm_LargeAreaLowGrayLevelEmphasis, stored as "./dataset/glszm/kernel5-radius5/tumor/BraTS2021_00283/original_glszm_LargeAreaLowGrayLevelEmphasis.nrrd"
# Computed original_glszm_LowGrayLevelZoneEmphasis, stored as "./dataset/glszm/kernel5-radius5/tumor/BraTS2021_00283/original_glszm_LowGrayLevelZoneEmphasis.nrrd"
# Computed original_glszm_SizeZoneNonUniformity, stored as "./dataset/glszm/kernel5-radius5/tumor/BraTS2021_00283/original_glszm_SizeZoneNonUniformity.nrrd"
# Computed original_glszm_SizeZoneNonUniformityNormalized, stored as "./dataset/glszm/kernel5-radius5/tumor/BraTS2021_00283/original_glszm_SizeZoneNonUniformityNormalized.nrrd"
# Computed original_glszm_SmallAreaEmphasis, stored as "./dataset/glszm/kernel5-radius5/tumor/BraTS2021_00283/original_glszm_SmallAreaEmphasis.nrrd"
# Computed original_glszm_SmallAreaHighGrayLevelEmphasis, stored as "./dataset/glszm/kernel5-radius5/tumor/BraTS2021_00283/original_glszm_SmallAreaHighGrayLevelEmphasis.nrrd"
# Computed original_glszm_SmallAreaLowGrayLevelEmphasis, stored as "./dataset/glszm/kernel5-radius5/tumor/BraTS2021_00283/original_glszm_SmallAreaLowGrayLevelEmphasis.nrrd"
# Computed original_glszm_ZoneEntropy, stored as "./dataset/glszm/kernel5-radius5/tumor/BraTS2021_00283/original_glszm_ZoneEntropy.nrrd"
# Computed original_glszm_ZonePercentage, stored as "./dataset/glszm/kernel5-radius5/tumor/BraTS2021_00283/original_glszm_ZonePercentage.nrrd"
# Computed original_glszm_ZoneVariance, stored as "./dataset/glszm/kernel5-radius5/tumor/BraTS2021_00283/original_glszm_ZoneVariance.nrrd"
# Starting BraTS2021_00284
# Computed original_glszm_GrayLevelNonUniformity, stored as "./dataset/glszm/kernel5-radius5/tumor/BraTS2021_00284/original_glszm_GrayLevelNonUniformity.nrrd"
# Computed original_glszm_GrayLevelNonUniformityNormalized, stored as "./dataset/glszm/kernel5-radius5/tumor/BraTS2021_00284/original_glszm_GrayLevelNonUniformityNormalized.nrrd"
# Computed original_glszm_GrayLevelVariance, stored as "./dataset/glszm/kernel5-radius5/tumor/BraTS2021_00284/original_glszm_GrayLevelVariance.nrrd"
# Computed original_glszm_HighGrayLevelZoneEmphasis, stored as "./dataset/glszm/kernel5-radius5/tumor/BraTS2021_00284/original_glszm_HighGrayLevelZoneEmphasis.nrrd"
# Computed original_glszm_LargeAreaEmphasis, stored as "./dataset/glszm/kernel5-radius5/tumor/BraTS2021_00284/original_glszm_LargeAreaEmphasis.nrrd"
# Computed original_glszm_LargeAreaHighGrayLevelEmphasis, stored as "./dataset/glszm/kernel5-radius5/tumor/BraTS2021_00284/original_glszm_LargeAreaHighGrayLevelEmphasis.nrrd"
# Computed original_glszm_LargeAreaLowGrayLevelEmphasis, stored as "./dataset/glszm/kernel5-radius5/tumor/BraTS2021_00284/original_glszm_LargeAreaLowGrayLevelEmphasis.nrrd"
# Computed original_glszm_LowGrayLevelZoneEmphasis, stored as "./dataset/glszm/kernel5-radius5/tumor/BraTS2021_00284/original_glszm_LowGrayLevelZoneEmphasis.nrrd"
# Computed original_glszm_SizeZoneNonUniformity, stored as "./dataset/glszm/kernel5-radius5/tumor/BraTS2021_00284/original_glszm_SizeZoneNonUniformity.nrrd"
# Computed original_glszm_SizeZoneNonUniformityNormalized, stored as "./dataset/glszm/kernel5-radius5/tumor/BraTS2021_00284/original_glszm_SizeZoneNonUniformityNormalized.nrrd"
# Computed original_glszm_SmallAreaEmphasis, stored as "./dataset/glszm/kernel5-radius5/tumor/BraTS2021_00284/original_glszm_SmallAreaEmphasis.nrrd"
# Computed original_glszm_SmallAreaHighGrayLevelEmphasis, stored as "./dataset/glszm/kernel5-radius5/tumor/BraTS2021_00284/original_glszm_SmallAreaHighGrayLevelEmphasis.nrrd"
# Computed original_glszm_SmallAreaLowGrayLevelEmphasis, stored as "./dataset/glszm/kernel5-radius5/tumor/BraTS2021_00284/original_glszm_SmallAreaLowGrayLevelEmphasis.nrrd"
# Computed original_glszm_ZoneEntropy, stored as "./dataset/glszm/kernel5-radius5/tumor/BraTS2021_00284/original_glszm_ZoneEntropy.nrrd"
# Computed original_glszm_ZonePercentage, stored as "./dataset/glszm/kernel5-radius5/tumor/BraTS2021_00284/original_glszm_ZonePercentage.nrrd"
# Computed original_glszm_ZoneVariance, stored as "./dataset/glszm/kernel5-radius5/tumor/BraTS2021_00284/original_glszm_ZoneVariance.nrrd"
# Starting BraTS2021_00285
# Computed original_glszm_GrayLevelNonUniformity, stored as "./dataset/glszm/kernel5-radius5/tumor/BraTS2021_00285/original_glszm_GrayLevelNonUniformity.nrrd"
# Computed original_glszm_GrayLevelNonUniformityNormalized, stored as "./dataset/glszm/kernel5-radius5/tumor/BraTS2021_00285/original_glszm_GrayLevelNonUniformityNormalized.nrrd"
# Computed original_glszm_GrayLevelVariance, stored as "./dataset/glszm/kernel5-radius5/tumor/BraTS2021_00285/original_glszm_GrayLevelVariance.nrrd"
# Computed original_glszm_HighGrayLevelZoneEmphasis, stored as "./dataset/glszm/kernel5-radius5/tumor/BraTS2021_00285/original_glszm_HighGrayLevelZoneEmphasis.nrrd"
# Computed original_glszm_LargeAreaEmphasis, stored as "./dataset/glszm/kernel5-radius5/tumor/BraTS2021_00285/original_glszm_LargeAreaEmphasis.nrrd"
# Computed original_glszm_LargeAreaHighGrayLevelEmphasis, stored as "./dataset/glszm/kernel5-radius5/tumor/BraTS2021_00285/original_glszm_LargeAreaHighGrayLevelEmphasis.nrrd"
# Computed original_glszm_LargeAreaLowGrayLevelEmphasis, stored as "./dataset/glszm/kernel5-radius5/tumor/BraTS2021_00285/original_glszm_LargeAreaLowGrayLevelEmphasis.nrrd"
# Computed original_glszm_LowGrayLevelZoneEmphasis, stored as "./dataset/glszm/kernel5-radius5/tumor/BraTS2021_00285/original_glszm_LowGrayLevelZoneEmphasis.nrrd"
# Computed original_glszm_SizeZoneNonUniformity, stored as "./dataset/glszm/kernel5-radius5/tumor/BraTS2021_00285/original_glszm_SizeZoneNonUniformity.nrrd"
# Computed original_glszm_SizeZoneNonUniformityNormalized, stored as "./dataset/glszm/kernel5-radius5/tumor/BraTS2021_00285/original_glszm_SizeZoneNonUniformityNormalized.nrrd"
# Computed original_glszm_SmallAreaEmphasis, stored as "./dataset/glszm/kernel5-radius5/tumor/BraTS2021_00285/original_glszm_SmallAreaEmphasis.nrrd"
# Computed original_glszm_SmallAreaHighGrayLevelEmphasis, stored as "./dataset/glszm/kernel5-radius5/tumor/BraTS2021_00285/original_glszm_SmallAreaHighGrayLevelEmphasis.nrrd"
# Computed original_glszm_SmallAreaLowGrayLevelEmphasis, stored as "./dataset/glszm/kernel5-radius5/tumor/BraTS2021_00285/original_glszm_SmallAreaLowGrayLevelEmphasis.nrrd"
# Computed original_glszm_ZoneEntropy, stored as "./dataset/glszm/kernel5-radius5/tumor/BraTS2021_00285/original_glszm_ZoneEntropy.nrrd"
# Computed original_glszm_ZonePercentage, stored as "./dataset/glszm/kernel5-radius5/tumor/BraTS2021_00285/original_glszm_ZonePercentage.nrrd"
# Computed original_glszm_ZoneVariance, stored as "./dataset/glszm/kernel5-radius5/tumor/BraTS2021_00285/original_glszm_ZoneVariance.nrrd"

# %% [markdown]
# <a href="https://colab.research.google.com/github/ntatfff/todo/blob/202411241258/ColabRadiomicsFeatureExtractor.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>
