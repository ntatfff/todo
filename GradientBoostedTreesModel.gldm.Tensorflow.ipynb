# %%
# Import packages and modules
import numpy  as np
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow_decision_forests as tfdf

from sklearn.model_selection import train_test_split
# Out:
# 2026-05-18 17:50:36.395313: I tensorflow/core/util/port.cc:113] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2026-05-18 17:50:36.483209: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2026-05-18 17:50:37.646676: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
# Check the version of TensorFlow Decision Forests
print("Found TensorFlow Decision Forests v" + tfdf.__version__)
# Out:
# Found TensorFlow Decision Forests v1.9.1

# %%
# train/validation/test = 70/10/20
dataset = pd.read_csv('dataset/gldm/kernel5-radius5/dataset.csv')

train_data, temp_data = train_test_split(
    dataset, test_size=0.3, random_state=42
 )
validation_data, test_data = train_test_split(
    temp_data, test_size=2/3, random_state=42
 )

# %%
# Convert the dataset into a TensorFlow dataset.
train_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    train_data, label="label"
)         
val_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    validation_data, label="label"
)
test_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    test_data, label="label"
)
# Out:
# 2026-05-18 17:50:42.114853: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:984] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2026-05-18 17:50:42.115717: W tensorflow/core/common_runtime/gpu/gpu_device.cc:2251] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...

# %%
import keras

# %%
# %%time

# Train a Gradient Boosted Trees model.
model = tfdf.keras.GradientBoostedTreesModel()

# Add evaluation metrics
model.compile(
    metrics=["accuracy"]
)
model.fit(x=train_ds)

# # Train a Gradient Boosted Trees model.
# model = tfdf.keras.GradientBoostedTreesModel(num_trees=1500)
# model.fit(train_ds)
# Out:
# Use /tmp/tmpx5_0hem_ as temporary training directory
# [WARNING
# Reading training dataset...
#  26-05-18 17:50:42.3751 UTC gradient_boosted_trees.cc:1840] "goss_alpha" set but "sampling_method" not equal to "GOSS".
# [WARNING 26-05-18 17:50:42.3753 UTC gradient_boosted_trees.cc:1851] "goss_beta" set but "sampling_method" not equal to "GOSS".
# [WARNING 26-05-18 17:50:42.3754 UTC gradient_boosted_trees.cc:1865] "selective_gradient_boosting_ratio" set but "sampling_method" not equal to "SELGB".
# Training dataset read in 0:00:05.985908. Found 78035 examples.
# Training model...
# Model trained in 0:00:47.149825
# Compiling model...
# [INFO 26-05-18 17:51:35.5679 UTC kernel.cc:1233] Loading model from path /tmp/tmpx5_0hem_/model/ with prefix 42d109c8cc5e41d1
# [INFO 26-05-18 17:51:35.5927 UTC quick_scorer_extended.cc:911] The binary was compiled without AVX2 support, but your CPU supports it. Enable it for faster model inference.
# [INFO 26-05-18 17:51:35.5944 UTC abstract_model.cc:1362] Engine "GradientBoostedTreesQuickScorerExtended" built
# [INFO 26-05-18 17:51:35.5944 UTC kernel.cc:1061] Use fast generic engine
# Model compiled.
# CPU times: user 1min 57s, sys: 2.82 s, total: 2min
# Wall time: 58.5 s

# %%
# Evaluate the model
evaluate = model.evaluate(val_ds, return_dict=True)
print()

for name, value in evaluate.items():
    print(f"{name}: {value:.4f}")
# Out:
# 12/12 [==============================] - 6s 8ms/step - loss: 0.0000e+00 - accuracy: 0.9617
#
# loss: 0.0000
# accuracy: 0.9617

# %%
# Model Summary
model.summary()
# Out:
# Model: "gradient_boosted_trees_model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
# =================================================================
# Total params: 1 (1.00 Byte)
# Trainable params: 0 (0.00 Byte)
# Non-trainable params: 1 (1.00 Byte)
# _________________________________________________________________
# Type: "GRADIENT_BOOSTED_TREES"
# Task: CLASSIFICATION
# Label: "__LABEL"
#
# Input Features (14):
# 	DependenceEntropy
# 	DependenceNonUniformity
# 	DependenceNonUniformityNormalized
# 	DependenceVariance
# 	GrayLevelNonUniformity
# 	GrayLevelVariance
# 	HighGrayLevelEmphasis
# 	LargeDependenceEmphasis
# 	LargeDependenceHighGrayLevelEmphasis
# 	LargeDependenceLowGrayLevelEmphasis
# 	LowGrayLevelEmphasis
# 	SmallDependenceEmphasis
# 	SmallDependenceHighGrayLevelEmphasis
# 	SmallDependenceLowGrayLevelEmphasis
#
# No weights
#
# Variable Importance: INV_MEAN_MIN_DEPTH:
#     1. "LargeDependenceHighGrayLevelEmphasis"  0.281637 ################
#     2.               "GrayLevelNonUniformity"  0.235017 ########
#     3.                "HighGrayLevelEmphasis"  0.216082 ######
#     4.                    "DependenceEntropy"  0.210884 #####
#     5. "SmallDependenceHighGrayLevelEmphasis"  0.207943 ####
#     6.  "SmallDependenceLowGrayLevelEmphasis"  0.205387 ####
#     7.                    "GrayLevelVariance"  0.204365 ####
#     8.              "SmallDependenceEmphasis"  0.199546 ###
#     9.  "LargeDependenceLowGrayLevelEmphasis"  0.192357 ##
#    10.                 "LowGrayLevelEmphasis"  0.190632 ##
#    11.                   "DependenceVariance"  0.189813 #
#    12.              "DependenceNonUniformity"  0.178768
#    13.    "DependenceNonUniformityNormalized"  0.177814
#    14.              "LargeDependenceEmphasis"  0.176698
#
# Variable Importance: NUM_AS_ROOT:
#     1. "LargeDependenceHighGrayLevelEmphasis" 80.000000 ################
#     2.               "GrayLevelNonUniformity" 49.000000 #########
#     3.                "HighGrayLevelEmphasis" 31.000000 ######
#     4.                    "GrayLevelVariance" 19.000000 ###
#     5. "SmallDependenceHighGrayLevelEmphasis" 13.000000 ##
#     6.                 "LowGrayLevelEmphasis" 11.000000 ##
#     7.                    "DependenceEntropy" 10.000000 #
#     8.                   "DependenceVariance"  9.000000 #
#     9.  "LargeDependenceLowGrayLevelEmphasis"  7.000000 #
#    10.              "SmallDependenceEmphasis"  7.000000 #
#    11.  "SmallDependenceLowGrayLevelEmphasis"  3.000000
#    12.              "DependenceNonUniformity"  2.000000
#    13.    "DependenceNonUniformityNormalized"  1.000000
#
# Variable Importance: NUM_NODES:
#     1.                    "DependenceEntropy" 760.000000 ################
#     2. "LargeDependenceHighGrayLevelEmphasis" 728.000000 ###############
#     3.               "GrayLevelNonUniformity" 610.000000 ############
#     4.  "SmallDependenceLowGrayLevelEmphasis" 568.000000 ###########
#     5. "SmallDependenceHighGrayLevelEmphasis" 505.000000 #########
#     6.                "HighGrayLevelEmphasis" 503.000000 #########
#     7.                    "GrayLevelVariance" 495.000000 #########
#     8.              "SmallDependenceEmphasis" 394.000000 ######
#     9.  "LargeDependenceLowGrayLevelEmphasis" 370.000000 ######
#    10.                   "DependenceVariance" 330.000000 #####
#    11.                 "LowGrayLevelEmphasis" 276.000000 ###
#    12.              "LargeDependenceEmphasis" 143.000000
#    13.              "DependenceNonUniformity" 125.000000
#    14.    "DependenceNonUniformityNormalized" 121.000000
#
# Variable Importance: SUM_SCORE:
#     1.                "HighGrayLevelEmphasis" 7010.040685 ################
#     2.                    "DependenceEntropy" 2025.985496 ####
#     3. "LargeDependenceHighGrayLevelEmphasis" 1742.770076 ###
#     4.               "GrayLevelNonUniformity" 861.301006 #
#     5.  "SmallDependenceLowGrayLevelEmphasis" 588.762829 #
#     6. "SmallDependenceHighGrayLevelEmphasis" 586.238137 #
#     7.                 "LowGrayLevelEmphasis" 541.214726 #
#     8.              "SmallDependenceEmphasis" 460.719384
#     9.                    "GrayLevelVariance" 355.113947
#    10.                   "DependenceVariance" 306.746727
#    11.  "LargeDependenceLowGrayLevelEmphasis" 298.571290
#    12.              "LargeDependenceEmphasis" 168.713972
#    13.              "DependenceNonUniformity" 64.118920
#    14.    "DependenceNonUniformityNormalized" 58.223771
#
#
#
# Loss: BINOMIAL_LOG_LIKELIHOOD
# Validation loss value: 0.210682
# Number of trees per iteration: 1
# Node format: NOT_SET
# Number of trees: 242
# Total number of nodes: 12098
#
# Number of nodes by tree:
# Count: 242 Average: 49.9917 StdDev: 8.62678
# Min: 17 Max: 63 Ignored: 0
# ----------------------------------------------
# [ 17, 19)  1   0.41%   0.41%
# [ 19, 21)  0   0.00%   0.41%
# [ 21, 24)  0   0.00%   0.41%
# [ 24, 26)  1   0.41%   0.83%
# [ 26, 28)  1   0.41%   1.24%
# [ 28, 31)  1   0.41%   1.65%
# [ 31, 33)  2   0.83%   2.48%
# [ 33, 35)  6   2.48%   4.96% #
# [ 35, 38)  9   3.72%   8.68% ##
# [ 38, 40)  5   2.07%  10.74% #
# [ 40, 42) 19   7.85%  18.60% ####
# [ 42, 45) 17   7.02%  25.62% ####
# [ 45, 47) 12   4.96%  30.58% ###
# [ 47, 49) 18   7.44%  38.02% ####
# [ 49, 52) 44  18.18%  56.20% ##########
# [ 52, 54) 22   9.09%  65.29% #####
# [ 54, 56) 20   8.26%  73.55% #####
# [ 56, 59) 15   6.20%  79.75% ###
# [ 59, 61) 17   7.02%  86.78% ####
# [ 61, 63] 32  13.22% 100.00% #######
#
# Depth by leafs:
# Count: 6170 Average: 4.81313 StdDev: 0.521427
# Min: 2 Max: 5 Ignored: 0
# ----------------------------------------------
# [ 2, 3)   51   0.83%   0.83%
# [ 3, 4)  217   3.52%   4.34%
# [ 4, 5)  566   9.17%  13.52% #
# [ 5, 5] 5336  86.48% 100.00% ##########
#
# Number of training obs by leaf:
# Count: 6170 Average: 2754.29 StdDev: 10255.3
# Min: 5 Max: 69904 Ignored: 0
# ----------------------------------------------
# [     5,  3500) 5555  90.03%  90.03% ##########
# [  3500,  6995)  170   2.76%  92.79%
# [  6995, 10490)   65   1.05%  93.84%
# [ 10490, 13985)   52   0.84%  94.68%
# [ 13985, 17480)   29   0.47%  95.15%
# [ 17480, 20975)   37   0.60%  95.75%
# [ 20975, 24470)   25   0.41%  96.16%
# [ 24470, 27965)   21   0.34%  96.50%
# [ 27965, 31460)   14   0.23%  96.73%
# [ 31460, 34955)   14   0.23%  96.95%
# [ 34955, 38450)   13   0.21%  97.16%
# [ 38450, 41945)   16   0.26%  97.42%
# [ 41945, 45440)   16   0.26%  97.68%
# [ 45440, 48935)   17   0.28%  97.96%
# [ 48935, 52430)   14   0.23%  98.18%
# [ 52430, 55925)    9   0.15%  98.33%
# [ 55925, 59420)   14   0.23%  98.56%
# [ 59420, 62915)   19   0.31%  98.87%
# [ 62915, 66410)   33   0.53%  99.40%
# [ 66410, 69904]   37   0.60% 100.00%
#
# Attribute in nodes:
# 	760 : DependenceEntropy [NUMERICAL]
# 	728 : LargeDependenceHighGrayLevelEmphasis [NUMERICAL]
# 	610 : GrayLevelNonUniformity [NUMERICAL]
# 	568 : SmallDependenceLowGrayLevelEmphasis [NUMERICAL]
# 	505 : SmallDependenceHighGrayLevelEmphasis [NUMERICAL]
# 	503 : HighGrayLevelEmphasis [NUMERICAL]
# 	495 : GrayLevelVariance [NUMERICAL]
# 	394 : SmallDependenceEmphasis [NUMERICAL]
# 	370 : LargeDependenceLowGrayLevelEmphasis [NUMERICAL]
# 	330 : DependenceVariance [NUMERICAL]
# 	276 : LowGrayLevelEmphasis [NUMERICAL]
# 	143 : LargeDependenceEmphasis [NUMERICAL]
# 	125 : DependenceNonUniformity [NUMERICAL]
# 	121 : DependenceNonUniformityNormalized [NUMERICAL]
#
# Attribute in nodes with depth <= 0:
# 	80 : LargeDependenceHighGrayLevelEmphasis [NUMERICAL]
# 	49 : GrayLevelNonUniformity [NUMERICAL]
# 	31 : HighGrayLevelEmphasis [NUMERICAL]
# 	19 : GrayLevelVariance [NUMERICAL]
# 	13 : SmallDependenceHighGrayLevelEmphasis [NUMERICAL]
# 	11 : LowGrayLevelEmphasis [NUMERICAL]
# 	10 : DependenceEntropy [NUMERICAL]
# 	9 : DependenceVariance [NUMERICAL]
# 	7 : SmallDependenceEmphasis [NUMERICAL]
# 	7 : LargeDependenceLowGrayLevelEmphasis [NUMERICAL]
# 	3 : SmallDependenceLowGrayLevelEmphasis [NUMERICAL]
# 	2 : DependenceNonUniformity [NUMERICAL]
# 	1 : DependenceNonUniformityNormalized [NUMERICAL]
#
# Attribute in nodes with depth <= 1:
# 	169 : LargeDependenceHighGrayLevelEmphasis [NUMERICAL]
# 	122 : GrayLevelNonUniformity [NUMERICAL]
# 	70 : SmallDependenceLowGrayLevelEmphasis [NUMERICAL]
# 	69 : SmallDependenceHighGrayLevelEmphasis [NUMERICAL]
# 	66 : HighGrayLevelEmphasis [NUMERICAL]
# 	50 : GrayLevelVariance [NUMERICAL]
# 	41 : SmallDependenceEmphasis [NUMERICAL]
# 	40 : DependenceEntropy [NUMERICAL]
# 	27 : LargeDependenceLowGrayLevelEmphasis [NUMERICAL]
# 	27 : DependenceVariance [NUMERICAL]
# 	26 : LowGrayLevelEmphasis [NUMERICAL]
# 	11 : DependenceNonUniformity [NUMERICAL]
# 	6 : DependenceNonUniformityNormalized [NUMERICAL]
# 	2 : LargeDependenceEmphasis [NUMERICAL]
#
# Attribute in nodes with depth <= 2:
# 	234 : LargeDependenceHighGrayLevelEmphasis [NUMERICAL]
# 	214 : GrayLevelNonUniformity [NUMERICAL]
# 	182 : SmallDependenceLowGrayLevelEmphasis [NUMERICAL]
# 	181 : DependenceEntropy [NUMERICAL]
# 	149 : HighGrayLevelEmphasis [NUMERICAL]
# 	133 : SmallDependenceHighGrayLevelEmphasis [NUMERICAL]
# 	123 : GrayLevelVariance [NUMERICAL]
# 	119 : SmallDependenceEmphasis [NUMERICAL]
# 	84 : LargeDependenceLowGrayLevelEmphasis [NUMERICAL]
# 	79 : DependenceVariance [NUMERICAL]
# 	71 : LowGrayLevelEmphasis [NUMERICAL]
# 	29 : DependenceNonUniformityNormalized [NUMERICAL]
# 	24 : DependenceNonUniformity [NUMERICAL]
# 	21 : LargeDependenceEmphasis [NUMERICAL]
#
# Attribute in nodes with depth <= 3:
# 	401 : DependenceEntropy [NUMERICAL]
# 	388 : LargeDependenceHighGrayLevelEmphasis [NUMERICAL]
# 	387 : GrayLevelNonUniformity [NUMERICAL]
# 	330 : SmallDependenceLowGrayLevelEmphasis [NUMERICAL]
# 	279 : HighGrayLevelEmphasis [NUMERICAL]
# 	274 : SmallDependenceHighGrayLevelEmphasis [NUMERICAL]
# 	272 : GrayLevelVariance [NUMERICAL]
# 	231 : SmallDependenceEmphasis [NUMERICAL]
# 	190 : LargeDependenceLowGrayLevelEmphasis [NUMERICAL]
# 	173 : DependenceVariance [NUMERICAL]
# 	150 : LowGrayLevelEmphasis [NUMERICAL]
# 	63 : LargeDependenceEmphasis [NUMERICAL]
# 	62 : DependenceNonUniformityNormalized [NUMERICAL]
# 	60 : DependenceNonUniformity [NUMERICAL]
#
# Attribute in nodes with depth <= 5:
# 	760 : DependenceEntropy [NUMERICAL]
# 	728 : LargeDependenceHighGrayLevelEmphasis [NUMERICAL]
# 	610 : GrayLevelNonUniformity [NUMERICAL]
# 	568 : SmallDependenceLowGrayLevelEmphasis [NUMERICAL]
# 	505 : SmallDependenceHighGrayLevelEmphasis [NUMERICAL]
# 	503 : HighGrayLevelEmphasis [NUMERICAL]
# 	495 : GrayLevelVariance [NUMERICAL]
# 	394 : SmallDependenceEmphasis [NUMERICAL]
# 	370 : LargeDependenceLowGrayLevelEmphasis [NUMERICAL]
# 	330 : DependenceVariance [NUMERICAL]
# 	276 : LowGrayLevelEmphasis [NUMERICAL]
# 	143 : LargeDependenceEmphasis [NUMERICAL]
# 	125 : DependenceNonUniformity [NUMERICAL]
# 	121 : DependenceNonUniformityNormalized [NUMERICAL]
#
# Condition type in nodes:
# 	5928 : HigherCondition
# Condition type in nodes with depth <= 0:
# 	242 : HigherCondition
# Condition type in nodes with depth <= 1:
# 	726 : HigherCondition
# Condition type in nodes with depth <= 2:
# 	1643 : HigherCondition
# Condition type in nodes with depth <= 3:
# 	3260 : HigherCondition
# Condition type in nodes with depth <= 5:
# 	5928 : HigherCondition
#
# Training logs:
# Number of iteration to final model: 242
# 	Iter:1 train-loss:0.433235 valid-loss:0.436034  train-accuracy:0.928086 valid-accuracy:0.927931
# 	Iter:2 train-loss:0.400943 valid-loss:0.405694  train-accuracy:0.928086 valid-accuracy:0.927931
# 	Iter:3 train-loss:0.377343 valid-loss:0.383573  train-accuracy:0.928086 valid-accuracy:0.927931
# 	Iter:4 train-loss:0.359148 valid-loss:0.366341  train-accuracy:0.928157 valid-accuracy:0.927931
# 	Iter:5 train-loss:0.341336 valid-loss:0.349366  train-accuracy:0.941771 valid-accuracy:0.940604
# 	Iter:6 train-loss:0.328641 valid-loss:0.336858  train-accuracy:0.949803 valid-accuracy:0.948413
# 	Iter:16 train-loss:0.252986 valid-loss:0.265442  train-accuracy:0.961252 valid-accuracy:0.957117
# 	Iter:26 train-loss:0.223507 valid-loss:0.241560  train-accuracy:0.964954 valid-accuracy:0.961598
# 	Iter:36 train-loss:0.206477 valid-loss:0.229278  train-accuracy:0.966564 valid-accuracy:0.961854
# 	Iter:46 train-loss:0.196188 valid-loss:0.223520  train-accuracy:0.967589 valid-accuracy:0.963262
# 	Iter:56 train-loss:0.189922 valid-loss:0.220729  train-accuracy:0.968671 valid-accuracy:0.962878
# 	Iter:66 train-loss:0.184197 valid-loss:0.218971  train-accuracy:0.969412 valid-accuracy:0.963646
# 	Iter:76 train-loss:0.179675 valid-loss:0.217807  train-accuracy:0.970038 valid-accuracy:0.963518
# 	Iter:86 train-loss:0.175699 valid-loss:0.216063  train-accuracy:0.970821 valid-accuracy:0.963902
# 	Iter:96 train-loss:0.171668 valid-loss:0.214353  train-accuracy:0.971448 valid-accuracy:0.963902
# 	Iter:106 train-loss:0.168903 valid-loss:0.214236  train-accuracy:0.971847 valid-accuracy:0.964030
# 	Iter:116 train-loss:0.165668 valid-loss:0.214015  train-accuracy:0.972459 valid-accuracy:0.963518
# 	Iter:126 train-loss:0.162609 valid-loss:0.213218  train-accuracy:0.972986 valid-accuracy:0.964030
# 	Iter:136 train-loss:0.160099 valid-loss:0.212505  train-accuracy:0.973328 valid-accuracy:0.963774
# 	Iter:146 train-loss:0.157146 valid-loss:0.212232  train-accuracy:0.973826 valid-accuracy:0.963774
# 	Iter:156 train-loss:0.154437 valid-loss:0.212080  train-accuracy:0.974410 valid-accuracy:0.963902
# 	Iter:166 train-loss:0.151597 valid-loss:0.212090  train-accuracy:0.974880 valid-accuracy:0.963774
# 	Iter:176 train-loss:0.149645 valid-loss:0.212040  train-accuracy:0.975108 valid-accuracy:0.963902
# 	Iter:186 train-loss:0.147203 valid-loss:0.211620  train-accuracy:0.975492 valid-accuracy:0.963646
# 	Iter:196 train-loss:0.145288 valid-loss:0.211541  train-accuracy:0.975863 valid-accuracy:0.963774
# 	Iter:206 train-loss:0.143018 valid-loss:0.211354  train-accuracy:0.976190 valid-accuracy:0.963646
# 	Iter:216 train-loss:0.141376 valid-loss:0.211277  train-accuracy:0.976717 valid-accuracy:0.963262
# 	Iter:226 train-loss:0.139634 valid-loss:0.210787  train-accuracy:0.977030 valid-accuracy:0.963390
# 	Iter:236 train-loss:0.137883 valid-loss:0.211009  train-accuracy:0.977344 valid-accuracy:0.963646
# 	Iter:246 train-loss:0.136132 valid-loss:0.210895  train-accuracy:0.977628 valid-accuracy:0.963646
# 	Iter:256 train-loss:0.134572 valid-loss:0.210868  train-accuracy:0.978041 valid-accuracy:0.963774
# 	Iter:266 train-loss:0.133025 valid-loss:0.210943  train-accuracy:0.978340 valid-accuracy:0.964158

# %%
# Model features
model.make_inspector().features()
# Out:
# ["DependenceEntropy" (1; #0),
#  "DependenceNonUniformity" (1; #1),
#  "DependenceNonUniformityNormalized" (1; #2),
#  "DependenceVariance" (1; #3),
#  "GrayLevelNonUniformity" (1; #4),
#  "GrayLevelVariance" (1; #5),
#  "HighGrayLevelEmphasis" (1; #6),
#  "LargeDependenceEmphasis" (1; #7),
#  "LargeDependenceHighGrayLevelEmphasis" (1; #8),
#  "LargeDependenceLowGrayLevelEmphasis" (1; #9),
#  "LowGrayLevelEmphasis" (1; #10),
#  "SmallDependenceEmphasis" (1; #11),
#  "SmallDependenceHighGrayLevelEmphasis" (1; #12),
#  "SmallDependenceLowGrayLevelEmphasis" (1; #13)]

# %%
# Feature importance
model.make_inspector().variable_importances()
# Out:
# {'INV_MEAN_MIN_DEPTH': [("LargeDependenceHighGrayLevelEmphasis" (1; #8),
#    0.28163661301674725),
#   ("GrayLevelNonUniformity" (1; #4), 0.23501672667001636),
#   ("HighGrayLevelEmphasis" (1; #6), 0.21608216899200786),
#   ("DependenceEntropy" (1; #0), 0.21088375699533146),
#   ("SmallDependenceHighGrayLevelEmphasis" (1; #12), 0.2079427810743909),
#   ("SmallDependenceLowGrayLevelEmphasis" (1; #13), 0.20538704859410892),
#   ("GrayLevelVariance" (1; #5), 0.20436463854638565),
#   ("SmallDependenceEmphasis" (1; #11), 0.19954555515505412),
#   ("LargeDependenceLowGrayLevelEmphasis" (1; #9), 0.1923570842186388),
#   ("LowGrayLevelEmphasis" (1; #10), 0.19063154874699334),
#   ("DependenceVariance" (1; #3), 0.18981250938101404),
#   ("DependenceNonUniformity" (1; #1), 0.17876801539577006),
#   ("DependenceNonUniformityNormalized" (1; #2), 0.17781392705970436),
#   ("LargeDependenceEmphasis" (1; #7), 0.17669798029304418)],
#  'NUM_AS_ROOT': [("LargeDependenceHighGrayLevelEmphasis" (1; #8), 80.0),
#   ("GrayLevelNonUniformity" (1; #4), 49.0),
#   ("HighGrayLevelEmphasis" (1; #6), 31.0),
#   ("GrayLevelVariance" (1; #5), 19.0),
#   ("SmallDependenceHighGrayLevelEmphasis" (1; #12), 13.0),
#   ("LowGrayLevelEmphasis" (1; #10), 11.0),
#   ("DependenceEntropy" (1; #0), 10.0),
#   ("DependenceVariance" (1; #3), 9.0),
#   ("LargeDependenceLowGrayLevelEmphasis" (1; #9), 7.0),
#   ("SmallDependenceEmphasis" (1; #11), 7.0),
#   ("SmallDependenceLowGrayLevelEmphasis" (1; #13), 3.0),
#   ("DependenceNonUniformity" (1; #1), 2.0),
#   ("DependenceNonUniformityNormalized" (1; #2), 1.0)],
#  'SUM_SCORE': [("HighGrayLevelEmphasis" (1; #6), 7010.040684648985),
#   ("DependenceEntropy" (1; #0), 2025.985495878208),
#   ("LargeDependenceHighGrayLevelEmphasis" (1; #8), 1742.770075997084),
#   ("GrayLevelNonUniformity" (1; #4), 861.3010059295999),
#   ("SmallDependenceLowGrayLevelEmphasis" (1; #13), 588.7628289360887),
#   ("SmallDependenceHighGrayLevelEmphasis" (1; #12), 586.2381372898508),
#   ("LowGrayLevelEmphasis" (1; #10), 541.2147258602333),
#   ("SmallDependenceEmphasis" (1; #11), 460.71938355438203),
#   ("GrayLevelVariance" (1; #5), 355.1139474705353),
#   ("DependenceVariance" (1; #3), 306.74672706658487),
#   ("LargeDependenceLowGrayLevelEmphasis" (1; #9), 298.571289957496),
#   ("LargeDependenceEmphasis" (1; #7), 168.713971954076),
#   ("DependenceNonUniformity" (1; #1), 64.11891976565897),
#   ("DependenceNonUniformityNormalized" (1; #2), 58.22377144450422)],
#  'NUM_NODES': [("DependenceEntropy" (1; #0), 760.0),
#   ("LargeDependenceHighGrayLevelEmphasis" (1; #8), 728.0),
#   ("GrayLevelNonUniformity" (1; #4), 610.0),
#   ("SmallDependenceLowGrayLevelEmphasis" (1; #13), 568.0),
#   ("SmallDependenceHighGrayLevelEmphasis" (1; #12), 505.0),
#   ("HighGrayLevelEmphasis" (1; #6), 503.0),
#   ("GrayLevelVariance" (1; #5), 495.0),
#   ("SmallDependenceEmphasis" (1; #11), 394.0),
#   ("LargeDependenceLowGrayLevelEmphasis" (1; #9), 370.0),
#   ("DependenceVariance" (1; #3), 330.0),
#   ("LowGrayLevelEmphasis" (1; #10), 276.0),
#   ("LargeDependenceEmphasis" (1; #7), 143.0),
#   ("DependenceNonUniformity" (1; #1), 125.0),
#   ("DependenceNonUniformityNormalized" (1; #2), 121.0)]}

# %%
# Model self evaluation
model.make_inspector().evaluation()
# Out:
# Evaluation(num_examples=None, accuracy=0.9637736678123474, loss=0.2106817215681076, rmse=None, ndcg=None, aucs=None, auuc=None, qini=None)

# %%
logs = model.make_inspector().training_logs()

plt.figure(figsize=(12, 4))
plt.subplot(1, 2, 1)
plt.plot([log.num_trees for log in logs], [log.evaluation.accuracy for log in logs])
plt.xlabel("Number of trees")
plt.ylabel("Accuracy (out-of-bag)")
plt.subplot(1, 2, 2)
plt.plot([log.num_trees for log in logs], [log.evaluation.loss for log in logs])
plt.xlabel("Number of trees")
plt.ylabel("Logloss (out-of-bag)")
plt.show()

# %% [markdown]
# Calculate the score of our hold-out validation dataset

# %%
predictions = model.predict(val_ds)
y_true      = validation_data["label"]

from sklearn.metrics import roc_auc_score
ROC_AUC = roc_auc_score(y_true, predictions)
print("The ROC AUC score is %.5f" % ROC_AUC )
# Out:
# 12/12 [==============================] - 0s 8ms/step
# The ROC AUC score is 0.95579

# %%
# Compute binary classification metrics with sklearn
import numpy as np
from sklearn.metrics import (
    accuracy_score,
    precision_score,
    recall_score,
    f1_score,
    roc_auc_score,
    average_precision_score,
    confusion_matrix,
    classification_report,
    matthews_corrcoef,
    log_loss,
    brier_score_loss,
)

# Get predictions (probabilities or class labels)
preds = model.predict(test_ds)
# If model outputs probabilities, convert to labels by threshold 0.5
if preds.ndim == 2:
    # For TFDF classification, preds may be class probabilities with shape (N, 2)
    if preds.shape[1] == 2:
        pos_probs = preds[:, 1]
    else:
        # If single-probability column (positive class)
        pos_probs = preds[:, -1]
    y_pred = (pos_probs >= 0.5).astype(int)
else:
    # Already class labels
    y_pred = preds.astype(int)
    pos_probs = None

# Ground truth labels (must be 0/1 integers)
y_true = test_data["label"].astype(int).to_numpy()

# Core metrics
metrics = {}
metrics["accuracy"] = accuracy_score(y_true, y_pred)
metrics["precision"] = precision_score(y_true, y_pred, zero_division=0)
metrics["recall"] = recall_score(y_true, y_pred, zero_division=0)
metrics["f1"] = f1_score(y_true, y_pred, zero_division=0)
metrics["mcc"] = matthews_corrcoef(y_true, y_pred)

# Probabilistic metrics (only if we have probabilities)
if pos_probs is not None:
    metrics["roc_auc"] = roc_auc_score(y_true, pos_probs)
    metrics["pr_auc"] = average_precision_score(y_true, pos_probs)
    metrics["log_loss"] = log_loss(y_true, pos_probs, labels=[0,1])
    metrics["brier_score"] = brier_score_loss(y_true, pos_probs)

# Confusion matrix and detailed report
cm = confusion_matrix(y_true, y_pred, labels=[0,1])
report = classification_report(y_true, y_pred, digits=4)

print("Sklearn binary metrics:")
for k, v in metrics.items():
    print(f"{k}: {v:.4f}")
print("\nConfusion matrix:\n", cm)
print("\nClassification report:\n", report)
# Out:
# 23/23 [==============================] - 0s 8ms/step
# Sklearn binary metrics:
# accuracy: 0.9639
# precision: 0.8503
# recall: 0.6151
# f1: 0.7138
# mcc: 0.7054
# roc_auc: 0.9603
# pr_auc: 0.8079
# log_loss: 0.1047
# brier_score: 0.0281
#
# Confusion matrix:
#  [[20485   177]
#  [  629  1005]]
#
# Classification report:
#                precision    recall  f1-score   support
#
#            0     0.9702    0.9914    0.9807     20662
#            1     0.8503    0.6151    0.7138      1634
#
#     accuracy                         0.9639     22296
#    macro avg     0.9102    0.8032    0.8472     22296
# weighted avg     0.9614    0.9639    0.9611     22296
