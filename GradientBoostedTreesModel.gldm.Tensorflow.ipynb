# %%
# Import packages and modules
import numpy  as np
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow_decision_forests as tfdf

from sklearn.model_selection import train_test_split

# %%
# Check the version of TensorFlow Decision Forests
print("Found TensorFlow Decision Forests v" + tfdf.__version__)
# Out:
# Found TensorFlow Decision Forests v1.9.1

# %%
# train/validation/test = 70/10/20
dataset = pd.read_csv('dataset/gldm/kernel5-radius5/dataset.200p.csv')

train_data, temp_data = train_test_split(
    dataset, test_size=0.3, random_state=42
 )
validation_data, test_data = train_test_split(
    temp_data, test_size=2/3, random_state=42
 )

# %%
from sklearn.utils.class_weight import compute_class_weight

# tinh class weight tren tap train
classes = np.array([0, 1])
weights = compute_class_weight(class_weight="balanced", classes=classes, y=train_data["label"])
class_weight = {0: weights[0], 1: weights[1]}

# gan sample_weight cho tung dong
train_data["sample_weight"] = train_data["label"].map(class_weight)
validation_data["sample_weight"] = validation_data["label"].map(class_weight)
test_data["sample_weight"] = test_data["label"].map(class_weight)

# Convert the dataset into a TensorFlow dataset.
train_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    train_data, label="label", weight="sample_weight"
)         
val_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    validation_data, label="label", weight="sample_weight"
)
test_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    test_data, label="label", weight="sample_weight"
)

# %%
import keras

# %%
# %%time

# Train a Gradient Boosted Trees model.
model = tfdf.keras.GradientBoostedTreesModel()

# Add evaluation metrics
model.compile(
    metrics=["accuracy"]
)
model.fit(x=train_ds)

# # Train a Gradient Boosted Trees model.
# model = tfdf.keras.GradientBoostedTreesModel(num_trees=1500)
# model.fit(train_ds)
# Out:
# Use /tmp/tmpzblqt7zl as temporary training directory
# Reading training dataset...
# [WARNING 26-05-27 16:00:20.4601 UTC gradient_boosted_trees.cc:1840] "goss_alpha" set but "sampling_method" not equal to "GOSS".
# [WARNING 26-05-27 16:00:20.4601 UTC gradient_boosted_trees.cc:1851] "goss_beta" set but "sampling_method" not equal to "GOSS".
# [WARNING 26-05-27 16:00:20.4601 UTC gradient_boosted_trees.cc:1865] "selective_gradient_boosting_ratio" set but "sampling_method" not equal to "SELGB".
# Training dataset read in 0:00:00.783727. Found 156683 examples.
# Training model...
# Model trained in 0:00:24.726667
# Compiling model...
# Model compiled.
# CPU times: user 2min 46s, sys: 2.14 s, total: 2min 48s
# Wall time: 25.7 s
# [INFO 26-05-27 16:00:45.9664 UTC kernel.cc:1233] Loading model from path /tmp/tmpzblqt7zl/model/ with prefix c344c698140d4d66
# [INFO 26-05-27 16:00:45.9752 UTC quick_scorer_extended.cc:911] The binary was compiled without AVX2 support, but your CPU supports it. Enable it for faster model inference.
# [INFO 26-05-27 16:00:45.9760 UTC abstract_model.cc:1362] Engine "GradientBoostedTreesQuickScorerExtended" built
# [INFO 26-05-27 16:00:45.9760 UTC kernel.cc:1061] Use fast generic engine

# %%
# Evaluate the model
evaluate = model.evaluate(val_ds, return_dict=True)
print()

for name, value in evaluate.items():
    print(f"{name}: {value:.4f}")
# Out:
# WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0000e+00 - accuracy: 0.8930
#
# loss: 0.0000
# accuracy: 0.8930

# %%
# Model Summary
model.summary()
# Out:
# Model: "gradient_boosted_trees_model_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
# =================================================================
# Total params: 1 (1.00 Byte)
# Trainable params: 0 (0.00 Byte)
# Non-trainable params: 1 (1.00 Byte)
# _________________________________________________________________
# Type: "GRADIENT_BOOSTED_TREES"
# Task: CLASSIFICATION
# Label: "__LABEL"
#
# Input Features (14):
# 	DependenceEntropy
# 	DependenceNonUniformity
# 	DependenceNonUniformityNormalized
# 	DependenceVariance
# 	GrayLevelNonUniformity
# 	GrayLevelVariance
# 	HighGrayLevelEmphasis
# 	LargeDependenceEmphasis
# 	LargeDependenceHighGrayLevelEmphasis
# 	LargeDependenceLowGrayLevelEmphasis
# 	LowGrayLevelEmphasis
# 	SmallDependenceEmphasis
# 	SmallDependenceHighGrayLevelEmphasis
# 	SmallDependenceLowGrayLevelEmphasis
#
# Trained with weights
#
# Variable Importance: INV_MEAN_MIN_DEPTH:
#     1. "LargeDependenceHighGrayLevelEmphasis"  0.286515 ################
#     2.                    "DependenceEntropy"  0.223136 ######
#     3.  "SmallDependenceLowGrayLevelEmphasis"  0.218192 ######
#     4.               "GrayLevelNonUniformity"  0.206665 ####
#     5.                "HighGrayLevelEmphasis"  0.206612 ####
#     6.              "SmallDependenceEmphasis"  0.205862 ####
#     7.                 "LowGrayLevelEmphasis"  0.199277 ###
#     8.                    "GrayLevelVariance"  0.199258 ###
#     9. "SmallDependenceHighGrayLevelEmphasis"  0.195867 ###
#    10.                   "DependenceVariance"  0.184624 #
#    11.  "LargeDependenceLowGrayLevelEmphasis"  0.182571 #
#    12.              "LargeDependenceEmphasis"  0.176790
#    13.    "DependenceNonUniformityNormalized"  0.175093
#    14.              "DependenceNonUniformity"  0.174860
#
# Variable Importance: NUM_AS_ROOT:
#     1. "LargeDependenceHighGrayLevelEmphasis" 59.000000 ################
#     2.  "SmallDependenceLowGrayLevelEmphasis" 20.000000 #####
#     3.                    "DependenceEntropy" 19.000000 ####
#     4.                 "LowGrayLevelEmphasis" 17.000000 ####
#     5.               "GrayLevelNonUniformity" 15.000000 ###
#     6.                    "GrayLevelVariance" 10.000000 ##
#     7.                "HighGrayLevelEmphasis" 10.000000 ##
#     8.              "SmallDependenceEmphasis"  6.000000 #
#     9.                   "DependenceVariance"  4.000000
#    10.              "DependenceNonUniformity"  2.000000
#    11.    "DependenceNonUniformityNormalized"  2.000000
#
# Variable Importance: NUM_NODES:
#     1. "LargeDependenceHighGrayLevelEmphasis" 563.000000 ################
#     2.                    "DependenceEntropy" 496.000000 #############
#     3.                "HighGrayLevelEmphasis" 456.000000 ############
#     4. "SmallDependenceHighGrayLevelEmphasis" 433.000000 ###########
#     5.  "SmallDependenceLowGrayLevelEmphasis" 427.000000 ###########
#     6.              "SmallDependenceEmphasis" 390.000000 ##########
#     7.                    "GrayLevelVariance" 376.000000 #########
#     8.               "GrayLevelNonUniformity" 350.000000 ########
#     9.                 "LowGrayLevelEmphasis" 255.000000 #####
#    10.                   "DependenceVariance" 236.000000 #####
#    11.  "LargeDependenceLowGrayLevelEmphasis" 231.000000 #####
#    12.              "LargeDependenceEmphasis" 140.000000 ##
#    13.              "DependenceNonUniformity" 90.000000
#    14.    "DependenceNonUniformityNormalized" 78.000000
#
# Variable Importance: SUM_SCORE:
#     1.                 "LowGrayLevelEmphasis" 33594.746614 ################
#     2.                    "DependenceEntropy" 26295.094979 ############
#     3. "LargeDependenceHighGrayLevelEmphasis" 18123.231438 ########
#     4.                "HighGrayLevelEmphasis" 17700.032923 ########
#     5. "SmallDependenceHighGrayLevelEmphasis" 15296.698049 #######
#     6.  "SmallDependenceLowGrayLevelEmphasis" 9689.701295 ####
#     7.              "SmallDependenceEmphasis" 4819.553936 ##
#     8.               "GrayLevelNonUniformity" 3408.920333 #
#     9.                    "GrayLevelVariance" 2405.044699 #
#    10.                   "DependenceVariance" 2049.770313
#    11.  "LargeDependenceLowGrayLevelEmphasis" 1763.042362
#    12.              "LargeDependenceEmphasis" 833.903333
#    13.              "DependenceNonUniformity" 358.399344
#    14.    "DependenceNonUniformityNormalized" 287.662989
#
#
#
# Loss: BINOMIAL_LOG_LIKELIHOOD
# Validation loss value: 0.585489
# Number of trees per iteration: 1
# Node format: NOT_SET
# Number of trees: 164
# Total number of nodes: 9206
#
# Number of nodes by tree:
# Count: 164 Average: 56.1341 StdDev: 7.27887
# Min: 33 Max: 63 Ignored: 0
# ----------------------------------------------
# [ 33, 34)  2   1.22%   1.22%
# [ 34, 36)  2   1.22%   2.44%
# [ 36, 37)  0   0.00%   2.44%
# [ 37, 39)  0   0.00%   2.44%
# [ 39, 40)  0   0.00%   2.44%
# [ 40, 42)  1   0.61%   3.05%
# [ 42, 43)  0   0.00%   3.05%
# [ 43, 45)  6   3.66%   6.71% #
# [ 45, 46)  7   4.27%  10.98% #
# [ 46, 48)  7   4.27%  15.24% #
# [ 48, 50) 13   7.93%  23.17% ###
# [ 50, 51)  0   0.00%  23.17%
# [ 51, 53) 11   6.71%  29.88% ##
# [ 53, 54)  7   4.27%  34.15% #
# [ 54, 56)  6   3.66%  37.80% #
# [ 56, 57)  0   0.00%  37.80%
# [ 57, 59) 15   9.15%  46.95% ###
# [ 59, 60) 17  10.37%  57.32% ###
# [ 60, 62) 20  12.20%  69.51% ####
# [ 62, 63] 50  30.49% 100.00% ##########
#
# Depth by leafs:
# Count: 4685 Average: 4.91526 StdDev: 0.372868
# Min: 2 Max: 5 Ignored: 0
# ----------------------------------------------
# [ 2, 3)   22   0.47%   0.47%
# [ 3, 4)   78   1.66%   2.13%
# [ 4, 5)  175   3.74%   5.87%
# [ 5, 5] 4410  94.13% 100.00% ##########
#
# Number of training obs by leaf:
# Count: 4685 Average: 4937.75 StdDev: 15141.1
# Min: 5 Max: 131446 Ignored: 0
# ----------------------------------------------
# [      5,   6577) 4007  85.53%  85.53% ##########
# [   6577,  13149)  249   5.31%  90.84% #
# [  13149,  19721)  120   2.56%  93.40%
# [  19721,  26293)   77   1.64%  95.05%
# [  26293,  32865)   51   1.09%  96.14%
# [  32865,  39437)   29   0.62%  96.76%
# [  39437,  46009)   25   0.53%  97.29%
# [  46009,  52581)   13   0.28%  97.57%
# [  52581,  59153)    7   0.15%  97.72%
# [  59153,  65726)    8   0.17%  97.89%
# [  65726,  72298)   10   0.21%  98.10%
# [  72298,  78870)   20   0.43%  98.53%
# [  78870,  85442)   11   0.23%  98.76%
# [  85442,  92014)   11   0.23%  99.00%
# [  92014,  98586)    9   0.19%  99.19%
# [  98586, 105158)   15   0.32%  99.51%
# [ 105158, 111730)    8   0.17%  99.68%
# [ 111730, 118302)    5   0.11%  99.79%
# [ 118302, 124874)    6   0.13%  99.91%
# [ 124874, 131446]    4   0.09% 100.00%
#
# Attribute in nodes:
# 	563 : LargeDependenceHighGrayLevelEmphasis [NUMERICAL]
# 	496 : DependenceEntropy [NUMERICAL]
# 	456 : HighGrayLevelEmphasis [NUMERICAL]
# 	433 : SmallDependenceHighGrayLevelEmphasis [NUMERICAL]
# 	427 : SmallDependenceLowGrayLevelEmphasis [NUMERICAL]
# 	390 : SmallDependenceEmphasis [NUMERICAL]
# 	376 : GrayLevelVariance [NUMERICAL]
# 	350 : GrayLevelNonUniformity [NUMERICAL]
# 	255 : LowGrayLevelEmphasis [NUMERICAL]
# 	236 : DependenceVariance [NUMERICAL]
# 	231 : LargeDependenceLowGrayLevelEmphasis [NUMERICAL]
# 	140 : LargeDependenceEmphasis [NUMERICAL]
# 	90 : DependenceNonUniformity [NUMERICAL]
# 	78 : DependenceNonUniformityNormalized [NUMERICAL]
#
# Attribute in nodes with depth <= 0:
# 	59 : LargeDependenceHighGrayLevelEmphasis [NUMERICAL]
# 	20 : SmallDependenceLowGrayLevelEmphasis [NUMERICAL]
# 	19 : DependenceEntropy [NUMERICAL]
# 	17 : LowGrayLevelEmphasis [NUMERICAL]
# 	15 : GrayLevelNonUniformity [NUMERICAL]
# 	10 : HighGrayLevelEmphasis [NUMERICAL]
# 	10 : GrayLevelVariance [NUMERICAL]
# 	6 : SmallDependenceEmphasis [NUMERICAL]
# 	4 : DependenceVariance [NUMERICAL]
# 	2 : DependenceNonUniformityNormalized [NUMERICAL]
# 	2 : DependenceNonUniformity [NUMERICAL]
#
# Attribute in nodes with depth <= 1:
# 	121 : LargeDependenceHighGrayLevelEmphasis [NUMERICAL]
# 	56 : DependenceEntropy [NUMERICAL]
# 	55 : SmallDependenceLowGrayLevelEmphasis [NUMERICAL]
# 	46 : GrayLevelNonUniformity [NUMERICAL]
# 	44 : SmallDependenceEmphasis [NUMERICAL]
# 	41 : HighGrayLevelEmphasis [NUMERICAL]
# 	31 : GrayLevelVariance [NUMERICAL]
# 	28 : LowGrayLevelEmphasis [NUMERICAL]
# 	25 : SmallDependenceHighGrayLevelEmphasis [NUMERICAL]
# 	17 : DependenceVariance [NUMERICAL]
# 	10 : LargeDependenceLowGrayLevelEmphasis [NUMERICAL]
# 	8 : LargeDependenceEmphasis [NUMERICAL]
# 	5 : DependenceNonUniformityNormalized [NUMERICAL]
# 	5 : DependenceNonUniformity [NUMERICAL]
#
# Attribute in nodes with depth <= 2:
# 	204 : LargeDependenceHighGrayLevelEmphasis [NUMERICAL]
# 	112 : DependenceEntropy [NUMERICAL]
# 	111 : SmallDependenceLowGrayLevelEmphasis [NUMERICAL]
# 	108 : HighGrayLevelEmphasis [NUMERICAL]
# 	104 : SmallDependenceEmphasis [NUMERICAL]
# 	98 : GrayLevelNonUniformity [NUMERICAL]
# 	85 : SmallDependenceHighGrayLevelEmphasis [NUMERICAL]
# 	79 : GrayLevelVariance [NUMERICAL]
# 	58 : LowGrayLevelEmphasis [NUMERICAL]
# 	57 : DependenceVariance [NUMERICAL]
# 	51 : LargeDependenceLowGrayLevelEmphasis [NUMERICAL]
# 	23 : LargeDependenceEmphasis [NUMERICAL]
# 	21 : DependenceNonUniformityNormalized [NUMERICAL]
# 	15 : DependenceNonUniformity [NUMERICAL]
#
# Attribute in nodes with depth <= 3:
# 	342 : LargeDependenceHighGrayLevelEmphasis [NUMERICAL]
# 	253 : DependenceEntropy [NUMERICAL]
# 	246 : HighGrayLevelEmphasis [NUMERICAL]
# 	214 : SmallDependenceLowGrayLevelEmphasis [NUMERICAL]
# 	207 : SmallDependenceEmphasis [NUMERICAL]
# 	206 : SmallDependenceHighGrayLevelEmphasis [NUMERICAL]
# 	181 : GrayLevelVariance [NUMERICAL]
# 	175 : GrayLevelNonUniformity [NUMERICAL]
# 	126 : LowGrayLevelEmphasis [NUMERICAL]
# 	115 : DependenceVariance [NUMERICAL]
# 	111 : LargeDependenceLowGrayLevelEmphasis [NUMERICAL]
# 	61 : LargeDependenceEmphasis [NUMERICAL]
# 	43 : DependenceNonUniformity [NUMERICAL]
# 	36 : DependenceNonUniformityNormalized [NUMERICAL]
#
# Attribute in nodes with depth <= 5:
# 	563 : LargeDependenceHighGrayLevelEmphasis [NUMERICAL]
# 	496 : DependenceEntropy [NUMERICAL]
# 	456 : HighGrayLevelEmphasis [NUMERICAL]
# 	433 : SmallDependenceHighGrayLevelEmphasis [NUMERICAL]
# 	427 : SmallDependenceLowGrayLevelEmphasis [NUMERICAL]
# 	390 : SmallDependenceEmphasis [NUMERICAL]
# 	376 : GrayLevelVariance [NUMERICAL]
# 	350 : GrayLevelNonUniformity [NUMERICAL]
# 	255 : LowGrayLevelEmphasis [NUMERICAL]
# 	236 : DependenceVariance [NUMERICAL]
# 	231 : LargeDependenceLowGrayLevelEmphasis [NUMERICAL]
# 	140 : LargeDependenceEmphasis [NUMERICAL]
# 	90 : DependenceNonUniformity [NUMERICAL]
# 	78 : DependenceNonUniformityNormalized [NUMERICAL]
#
# Condition type in nodes:
# 	4521 : HigherCondition
# Condition type in nodes with depth <= 0:
# 	164 : HigherCondition
# Condition type in nodes with depth <= 1:
# 	492 : HigherCondition
# Condition type in nodes with depth <= 2:
# 	1126 : HigherCondition
# Condition type in nodes with depth <= 3:
# 	2316 : HigherCondition
# Condition type in nodes with depth <= 5:
# 	4521 : HigherCondition
#
# Training logs:
# Number of iteration to final model: 164
# 	Iter:1 train-loss:1.285608 valid-loss:1.288604  train-accuracy:0.837300 valid-accuracy:0.822686
# 	Iter:2 train-loss:1.202440 valid-loss:1.207779  train-accuracy:0.842395 valid-accuracy:0.829640
# 	Iter:3 train-loss:1.128413 valid-loss:1.136769  train-accuracy:0.847006 valid-accuracy:0.836070
# 	Iter:4 train-loss:1.066945 valid-loss:1.077062  train-accuracy:0.848836 valid-accuracy:0.836274
# 	Iter:5 train-loss:1.012992 valid-loss:1.024861  train-accuracy:0.850959 valid-accuracy:0.843105
# 	Iter:6 train-loss:0.966757 valid-loss:0.979903  train-accuracy:0.854551 valid-accuracy:0.843979
# 	Iter:16 train-loss:0.713816 valid-loss:0.741116  train-accuracy:0.872847 valid-accuracy:0.860291
# 	Iter:26 train-loss:0.624243 valid-loss:0.663164  train-accuracy:0.878447 valid-accuracy:0.865781
# 	Iter:36 train-loss:0.582733 valid-loss:0.629081  train-accuracy:0.882807 valid-accuracy:0.867495
# 	Iter:46 train-loss:0.559263 valid-loss:0.615745  train-accuracy:0.885694 valid-accuracy:0.869928
# 	Iter:56 train-loss:0.541894 valid-loss:0.604336  train-accuracy:0.889003 valid-accuracy:0.868084
# 	Iter:66 train-loss:0.528407 valid-loss:0.599498  train-accuracy:0.891966 valid-accuracy:0.867928
# 	Iter:76 train-loss:0.517992 valid-loss:0.595803  train-accuracy:0.893724 valid-accuracy:0.868321
# 	Iter:86 train-loss:0.509888 valid-loss:0.592908  train-accuracy:0.894840 valid-accuracy:0.870042
# 	Iter:96 train-loss:0.501626 valid-loss:0.590952  train-accuracy:0.896429 valid-accuracy:0.870198
# 	Iter:106 train-loss:0.494909 valid-loss:0.590477  train-accuracy:0.897782 valid-accuracy:0.869967
# 	Iter:116 train-loss:0.487865 valid-loss:0.588922  train-accuracy:0.899324 valid-accuracy:0.870611
# 	Iter:126 train-loss:0.481502 valid-loss:0.588660  train-accuracy:0.900682 valid-accuracy:0.870767
# 	Iter:136 train-loss:0.476075 valid-loss:0.587844  train-accuracy:0.902561 valid-accuracy:0.871208
# 	Iter:146 train-loss:0.470626 valid-loss:0.586770  train-accuracy:0.904107 valid-accuracy:0.872827
# 	Iter:156 train-loss:0.464034 valid-loss:0.586530  train-accuracy:0.906335 valid-accuracy:0.872075
# 	Iter:166 train-loss:0.458527 valid-loss:0.585926  train-accuracy:0.907884 valid-accuracy:0.873946
# 	Iter:176 train-loss:0.453597 valid-loss:0.585935  train-accuracy:0.909016 valid-accuracy:0.873241
# 	Iter:186 train-loss:0.449049 valid-loss:0.585629  train-accuracy:0.909981 valid-accuracy:0.873817

# %%
# Model features
model.make_inspector().features()
# Out:
# ["DependenceEntropy" (1; #0),
#  "DependenceNonUniformity" (1; #1),
#  "DependenceNonUniformityNormalized" (1; #2),
#  "DependenceVariance" (1; #3),
#  "GrayLevelNonUniformity" (1; #4),
#  "GrayLevelVariance" (1; #5),
#  "HighGrayLevelEmphasis" (1; #6),
#  "LargeDependenceEmphasis" (1; #7),
#  "LargeDependenceHighGrayLevelEmphasis" (1; #8),
#  "LargeDependenceLowGrayLevelEmphasis" (1; #9),
#  "LowGrayLevelEmphasis" (1; #10),
#  "SmallDependenceEmphasis" (1; #11),
#  "SmallDependenceHighGrayLevelEmphasis" (1; #12),
#  "SmallDependenceLowGrayLevelEmphasis" (1; #13)]

# %%
# Feature importance
model.make_inspector().variable_importances()
# Out:
# {'INV_MEAN_MIN_DEPTH': [("LargeDependenceHighGrayLevelEmphasis" (1; #8),
#    0.28651475941609766),
#   ("DependenceEntropy" (1; #0), 0.22313561357088388),
#   ("SmallDependenceLowGrayLevelEmphasis" (1; #13), 0.21819216062817426),
#   ("GrayLevelNonUniformity" (1; #4), 0.20666482953569681),
#   ("HighGrayLevelEmphasis" (1; #6), 0.2066121183360057),
#   ("SmallDependenceEmphasis" (1; #11), 0.20586245101886744),
#   ("LowGrayLevelEmphasis" (1; #10), 0.19927667702847754),
#   ("GrayLevelVariance" (1; #5), 0.19925845069703435),
#   ("SmallDependenceHighGrayLevelEmphasis" (1; #12), 0.195866942218856),
#   ("DependenceVariance" (1; #3), 0.18462406775123394),
#   ("LargeDependenceLowGrayLevelEmphasis" (1; #9), 0.1825706535817891),
#   ("LargeDependenceEmphasis" (1; #7), 0.17678988318942837),
#   ("DependenceNonUniformityNormalized" (1; #2), 0.17509280668384114),
#   ("DependenceNonUniformity" (1; #1), 0.17486026558694545)],
#  'SUM_SCORE': [("LowGrayLevelEmphasis" (1; #10), 33594.74661446796),
#   ("DependenceEntropy" (1; #0), 26295.094978594647),
#   ("LargeDependenceHighGrayLevelEmphasis" (1; #8), 18123.231437676586),
#   ("HighGrayLevelEmphasis" (1; #6), 17700.03292283087),
#   ("SmallDependenceHighGrayLevelEmphasis" (1; #12), 15296.69804902332),
#   ("SmallDependenceLowGrayLevelEmphasis" (1; #13), 9689.70129489117),
#   ("SmallDependenceEmphasis" (1; #11), 4819.553936036843),
#   ("GrayLevelNonUniformity" (1; #4), 3408.9203332180673),
#   ("GrayLevelVariance" (1; #5), 2405.044699305168),
#   ("DependenceVariance" (1; #3), 2049.770313480578),
#   ("LargeDependenceLowGrayLevelEmphasis" (1; #9), 1763.042362228395),
#   ("LargeDependenceEmphasis" (1; #7), 833.9033331017129),
#   ("DependenceNonUniformity" (1; #1), 358.3993443554664),
#   ("DependenceNonUniformityNormalized" (1; #2), 287.66298866937433)],
#  'NUM_AS_ROOT': [("LargeDependenceHighGrayLevelEmphasis" (1; #8), 59.0),
#   ("SmallDependenceLowGrayLevelEmphasis" (1; #13), 20.0),
#   ("DependenceEntropy" (1; #0), 19.0),
#   ("LowGrayLevelEmphasis" (1; #10), 17.0),
#   ("GrayLevelNonUniformity" (1; #4), 15.0),
#   ("GrayLevelVariance" (1; #5), 10.0),
#   ("HighGrayLevelEmphasis" (1; #6), 10.0),
#   ("SmallDependenceEmphasis" (1; #11), 6.0),
#   ("DependenceVariance" (1; #3), 4.0),
#   ("DependenceNonUniformity" (1; #1), 2.0),
#   ("DependenceNonUniformityNormalized" (1; #2), 2.0)],
#  'NUM_NODES': [("LargeDependenceHighGrayLevelEmphasis" (1; #8), 563.0),
#   ("DependenceEntropy" (1; #0), 496.0),
#   ("HighGrayLevelEmphasis" (1; #6), 456.0),
#   ("SmallDependenceHighGrayLevelEmphasis" (1; #12), 433.0),
#   ("SmallDependenceLowGrayLevelEmphasis" (1; #13), 427.0),
#   ("SmallDependenceEmphasis" (1; #11), 390.0),
#   ("GrayLevelVariance" (1; #5), 376.0),
#   ("GrayLevelNonUniformity" (1; #4), 350.0),
#   ("LowGrayLevelEmphasis" (1; #10), 255.0),
#   ("DependenceVariance" (1; #3), 236.0),
#   ("LargeDependenceLowGrayLevelEmphasis" (1; #9), 231.0),
#   ("LargeDependenceEmphasis" (1; #7), 140.0),
#   ("DependenceNonUniformity" (1; #1), 90.0),
#   ("DependenceNonUniformityNormalized" (1; #2), 78.0)]}

# %%
# Model self evaluation
model.make_inspector().evaluation()
# Out:
# Evaluation(num_examples=None, accuracy=0.8738440275192261, loss=0.5854893922805786, rmse=None, ndcg=None, aucs=None, auuc=None, qini=None)

# %%
logs = model.make_inspector().training_logs()

plt.figure(figsize=(12, 4))
plt.subplot(1, 2, 1)
plt.plot([log.num_trees for log in logs], [log.evaluation.accuracy for log in logs])
plt.xlabel("Number of trees")
plt.ylabel("Accuracy (out-of-bag)")
plt.subplot(1, 2, 2)
plt.plot([log.num_trees for log in logs], [log.evaluation.loss for log in logs])
plt.xlabel("Number of trees")
plt.ylabel("Logloss (out-of-bag)")
plt.show()

# %% [markdown]
# Calculate the score of our hold-out validation dataset

# %%
predictions = model.predict(val_ds)
y_true      = validation_data["label"]

from sklearn.metrics import roc_auc_score
ROC_AUC = roc_auc_score(y_true, predictions)
print("The ROC AUC score is %.5f" % ROC_AUC )
# Out:
#  1/23 [>.............................] - ETA: 1s
# 23/23 [==============================] - 0s 4ms/step
# The ROC AUC score is 0.95402

# %%
# Compute binary classification metrics with sklearn
import numpy as np
from sklearn.metrics import (
    accuracy_score,
    precision_score,
    recall_score,
    f1_score,
    roc_auc_score,
    average_precision_score,
    confusion_matrix,
    classification_report,
    matthews_corrcoef,
    log_loss,
    brier_score_loss,
)

# Get predictions (probabilities or class labels)
preds = model.predict(test_ds)
# If model outputs probabilities, convert to labels by threshold 0.5
if preds.ndim == 2:
    # For TFDF classification, preds may be class probabilities with shape (N, 2)
    if preds.shape[1] == 2:
        pos_probs = preds[:, 1]
    else:
        # If single-probability column (positive class)
        pos_probs = preds[:, -1]
    y_pred = (pos_probs >= 0.5).astype(int)
else:
    # Already class labels
    y_pred = preds.astype(int)
    pos_probs = None

# Ground truth labels (must be 0/1 integers)
y_true = test_data["label"].astype(int).to_numpy()

# Core metrics
metrics = {}
metrics["accuracy"] = accuracy_score(y_true, y_pred)
metrics["precision"] = precision_score(y_true, y_pred, zero_division=0)
metrics["recall"] = recall_score(y_true, y_pred, zero_division=0)
metrics["f1"] = f1_score(y_true, y_pred, zero_division=0)
metrics["mcc"] = matthews_corrcoef(y_true, y_pred)

# Probabilistic metrics (only if we have probabilities)
if pos_probs is not None:
    metrics["roc_auc"] = roc_auc_score(y_true, pos_probs)
    metrics["pr_auc"] = average_precision_score(y_true, pos_probs)
    metrics["log_loss"] = log_loss(y_true, pos_probs, labels=[0,1])
    metrics["brier_score"] = brier_score_loss(y_true, pos_probs)

# Confusion matrix and detailed report
cm = confusion_matrix(y_true, y_pred, labels=[0,1])
report = classification_report(y_true, y_pred, digits=4)

print("Sklearn binary metrics:")
for k, v in metrics.items():
    print(f"{k}: {v:.4f}")
print("\nConfusion matrix:\n", cm)
print("\nClassification report:\n", report)
# Out:
# 45/45 [==============================] - 0s 4ms/step
# Sklearn binary metrics:
# accuracy: 0.8895
# precision: 0.3501
# recall: 0.8652
# f1: 0.4985
# mcc: 0.5071
# roc_auc: 0.9525
# pr_auc: 0.7154
# log_loss: 0.2544
# brier_score: 0.0782
#
# Confusion matrix:
#  [[37361  4565]
#  [  383  2459]]
#
# Classification report:
#                precision    recall  f1-score   support
#
#            0     0.9899    0.8911    0.9379     41926
#            1     0.3501    0.8652    0.4985      2842
#
#     accuracy                         0.8895     44768
#    macro avg     0.6700    0.8782    0.7182     44768
# weighted avg     0.9492    0.8895    0.9100     44768
