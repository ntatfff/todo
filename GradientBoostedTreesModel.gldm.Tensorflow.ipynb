# %%
# Import packages and modules
import numpy  as np
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow_decision_forests as tfdf

from sklearn.model_selection import train_test_split
# Out:
# 2026-05-26 17:47:44.321262: I tensorflow/core/util/port.cc:113] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2026-05-26 17:47:44.376987: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2026-05-26 17:47:45.657859: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
# Check the version of TensorFlow Decision Forests
print("Found TensorFlow Decision Forests v" + tfdf.__version__)
# Out:
# Found TensorFlow Decision Forests v1.9.1

# %%
# train/validation/test = 70/10/20
dataset = pd.read_csv('dataset/gldm/kernel5-radius5/dataset.csv')

train_data, temp_data = train_test_split(
    dataset, test_size=0.3, random_state=42
 )
validation_data, test_data = train_test_split(
    temp_data, test_size=2/3, random_state=42
 )

# %%
from sklearn.utils.class_weight import compute_class_weight

# tinh class weight tren tap train
classes = np.array([0, 1])
weights = compute_class_weight(class_weight="balanced", classes=classes, y=train_data["label"])
class_weight = {0: weights[0], 1: weights[1]}

# gan sample_weight cho tung dong
train_data["sample_weight"] = train_data["label"].map(class_weight)
validation_data["sample_weight"] = validation_data["label"].map(class_weight)
test_data["sample_weight"] = test_data["label"].map(class_weight)

# Convert the dataset into a TensorFlow dataset.
train_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    train_data, label="label", weight="sample_weight"
)         
val_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    validation_data, label="label", weight="sample_weight"
)
test_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    test_data, label="label", weight="sample_weight"
)
# Out:
# 2026-05-26 17:47:47.963162: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:984] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2026-05-26 17:47:47.963502: W tensorflow/core/common_runtime/gpu/gpu_device.cc:2251] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...

# %%
import keras

# %%
# %%time

# Train a Gradient Boosted Trees model.
model = tfdf.keras.GradientBoostedTreesModel()

# Add evaluation metrics
model.compile(
    metrics=["accuracy"]
)
model.fit(x=train_ds)

# # Train a Gradient Boosted Trees model.
# model = tfdf.keras.GradientBoostedTreesModel(num_trees=1500)
# model.fit(train_ds)
# Out:
# Use /tmp/tmp298rsjhr as temporary training directory
# [WARNING 26-05-26 17:47:48.1476 UTC gradient_boosted_trees.cc:1840] "goss_alpha" set but "sampling_method" not equal to "GOSS".
# [WARNING 26-05-26 17:47:48.1477 UTC gradient_boosted_trees.cc:1851] "goss_beta" set but "sampling_method" not equal to "GOSS".
# [WARNING 26-05-26 17:47:48.1477 UTC gradient_boosted_trees.cc:1865] "selective_gradient_boosting_ratio" set but "sampling_method" not equal to "SELGB".
# Reading training dataset...
# Training dataset read in 0:00:04.740254. Found 78035 examples.
# Training model...
# Model trained in 0:00:15.761233
# Compiling model...
# [INFO 26-05-26 17:48:08.7047 UTC kernel.cc:1233] Loading model from path /tmp/tmp298rsjhr/model/ with prefix dd2442137b7c4685
# [INFO 26-05-26 17:48:08.7120 UTC quick_scorer_extended.cc:911] The binary was compiled without AVX2 support, but your CPU supports it. Enable it for faster model inference.
# [INFO 26-05-26 17:48:08.7123 UTC abstract_model.cc:1362] Engine "GradientBoostedTreesQuickScorerExtended" built
# [INFO 26-05-26 17:48:08.7123 UTC kernel.cc:1061] Use fast generic engine
# Model compiled.
# CPU times: user 57.1 s, sys: 1.42 s, total: 58.5 s
# Wall time: 24.4 s

# %%
# Evaluate the model
evaluate = model.evaluate(val_ds, return_dict=True)
print()

for name, value in evaluate.items():
    print(f"{name}: {value:.4f}")
# Out:
# WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 12/12 [==============================] - 4s 6ms/step - loss: 0.0000e+00 - accuracy: 0.9164
#
# loss: 0.0000
# accuracy: 0.9164

# %%
# Model Summary
model.summary()
# Out:
# Model: "gradient_boosted_trees_model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
# =================================================================
# Total params: 1 (1.00 Byte)
# Trainable params: 0 (0.00 Byte)
# Non-trainable params: 1 (1.00 Byte)
# _________________________________________________________________
# Type: "GRADIENT_BOOSTED_TREES"
# Task: CLASSIFICATION
# Label: "__LABEL"
#
# Input Features (14):
# 	DependenceEntropy
# 	DependenceNonUniformity
# 	DependenceNonUniformityNormalized
# 	DependenceVariance
# 	GrayLevelNonUniformity
# 	GrayLevelVariance
# 	HighGrayLevelEmphasis
# 	LargeDependenceEmphasis
# 	LargeDependenceHighGrayLevelEmphasis
# 	LargeDependenceLowGrayLevelEmphasis
# 	LowGrayLevelEmphasis
# 	SmallDependenceEmphasis
# 	SmallDependenceHighGrayLevelEmphasis
# 	SmallDependenceLowGrayLevelEmphasis
#
# Trained with weights
#
# Variable Importance: INV_MEAN_MIN_DEPTH:
#     1. "LargeDependenceHighGrayLevelEmphasis"  0.370448 ################
#     2.                    "DependenceEntropy"  0.234461 #####
#     3.                "HighGrayLevelEmphasis"  0.225264 ####
#     4.              "SmallDependenceEmphasis"  0.209703 ###
#     5. "SmallDependenceHighGrayLevelEmphasis"  0.200453 ##
#     6.  "SmallDependenceLowGrayLevelEmphasis"  0.197484 ##
#     7.               "GrayLevelNonUniformity"  0.196916 #
#     8.                    "GrayLevelVariance"  0.193171 #
#     9.  "LargeDependenceLowGrayLevelEmphasis"  0.186268 #
#    10.                   "DependenceVariance"  0.185171 #
#    11.                 "LowGrayLevelEmphasis"  0.182946
#    12.              "LargeDependenceEmphasis"  0.174760
#    13.              "DependenceNonUniformity"  0.172583
#    14.    "DependenceNonUniformityNormalized"  0.172373
#
# Variable Importance: NUM_AS_ROOT:
#     1. "LargeDependenceHighGrayLevelEmphasis" 53.000000 ################
#     2.                "HighGrayLevelEmphasis" 12.000000 ###
#     3.                    "DependenceEntropy"  8.000000 ##
#     4.  "SmallDependenceLowGrayLevelEmphasis"  6.000000 #
#     5.  "LargeDependenceLowGrayLevelEmphasis"  4.000000
#     6.               "GrayLevelNonUniformity"  3.000000
#     7.                    "GrayLevelVariance"  3.000000
#     8.                   "DependenceVariance"  1.000000
#     9.                 "LowGrayLevelEmphasis"  1.000000
#
# Variable Importance: NUM_NODES:
#     1.                    "DependenceEntropy" 358.000000 ################
#     2. "LargeDependenceHighGrayLevelEmphasis" 341.000000 ###############
#     3.                "HighGrayLevelEmphasis" 281.000000 ############
#     4. "SmallDependenceHighGrayLevelEmphasis" 238.000000 #########
#     5.                    "GrayLevelVariance" 222.000000 #########
#     6.              "SmallDependenceEmphasis" 214.000000 ########
#     7.  "SmallDependenceLowGrayLevelEmphasis" 199.000000 #######
#     8.               "GrayLevelNonUniformity" 158.000000 #####
#     9.  "LargeDependenceLowGrayLevelEmphasis" 139.000000 ####
#    10.                 "LowGrayLevelEmphasis" 134.000000 ####
#    11.                   "DependenceVariance" 127.000000 ####
#    12.              "LargeDependenceEmphasis" 64.000000 #
#    13.              "DependenceNonUniformity" 45.000000
#    14.    "DependenceNonUniformityNormalized" 41.000000
#
# Variable Importance: SUM_SCORE:
#     1.                "HighGrayLevelEmphasis" 21609.057604 ################
#     2. "LargeDependenceHighGrayLevelEmphasis" 16160.058146 ###########
#     3.                    "DependenceEntropy" 11421.726947 ########
#     4.              "SmallDependenceEmphasis" 8957.047777 ######
#     5.  "SmallDependenceLowGrayLevelEmphasis" 4396.064254 ###
#     6.                 "LowGrayLevelEmphasis" 2098.614064 #
#     7. "SmallDependenceHighGrayLevelEmphasis" 1813.910173 #
#     8.               "GrayLevelNonUniformity" 1714.604935 #
#     9.                   "DependenceVariance" 1162.158881
#    10.                    "GrayLevelVariance" 1121.180975
#    11.  "LargeDependenceLowGrayLevelEmphasis" 975.849508
#    12.              "LargeDependenceEmphasis" 639.190990
#    13.    "DependenceNonUniformityNormalized" 289.624713
#    14.              "DependenceNonUniformity" 217.956558
#
#
#
# Loss: BINOMIAL_LOG_LIKELIHOOD
# Validation loss value: 0.532576
# Number of trees per iteration: 1
# Node format: NOT_SET
# Number of trees: 91
# Total number of nodes: 5213
#
# Number of nodes by tree:
# Count: 91 Average: 57.2857 StdDev: 6.32158
# Min: 35 Max: 63 Ignored: 0
# ----------------------------------------------
# [ 35, 36)  1   1.10%   1.10%
# [ 36, 37)  0   0.00%   1.10%
# [ 37, 39)  0   0.00%   1.10%
# [ 39, 40)  0   0.00%   1.10%
# [ 40, 42)  1   1.10%   2.20%
# [ 42, 43)  0   0.00%   2.20%
# [ 43, 45)  4   4.40%   6.59% #
# [ 45, 46)  0   0.00%   6.59%
# [ 46, 48)  5   5.49%  12.09% ##
# [ 48, 49)  0   0.00%  12.09%
# [ 49, 50)  3   3.30%  15.38% #
# [ 50, 52)  3   3.30%  18.68% #
# [ 52, 53)  0   0.00%  18.68%
# [ 53, 55)  2   2.20%  20.88% #
# [ 55, 56) 11  12.09%  32.97% ####
# [ 56, 58)  8   8.79%  41.76% ###
# [ 58, 59)  0   0.00%  41.76%
# [ 59, 61) 12  13.19%  54.95% ####
# [ 61, 62) 14  15.38%  70.33% #####
# [ 62, 63] 27  29.67% 100.00% ##########
#
# Depth by leafs:
# Count: 2652 Average: 4.92345 StdDev: 0.330376
# Min: 2 Max: 5 Ignored: 0
# ----------------------------------------------
# [ 2, 3)    6   0.23%   0.23%
# [ 3, 4)   33   1.24%   1.47%
# [ 4, 5)  119   4.49%   5.96%
# [ 5, 5] 2494  94.04% 100.00% ##########
#
# Number of training obs by leaf:
# Count: 2652 Average: 2409.61 StdDev: 6743.8
# Min: 5 Max: 60344 Ignored: 0
# ----------------------------------------------
# [     5,  3022) 2229  84.05%  84.05% ##########
# [  3022,  6039)  189   7.13%  91.18% #
# [  6039,  9056)   55   2.07%  93.25%
# [  9056, 12073)   42   1.58%  94.83%
# [ 12073, 15090)   26   0.98%  95.81%
# [ 15090, 18107)   14   0.53%  96.34%
# [ 18107, 21124)   20   0.75%  97.10%
# [ 21124, 24141)   15   0.57%  97.66%
# [ 24141, 27158)   13   0.49%  98.15%
# [ 27158, 30175)    9   0.34%  98.49%
# [ 30175, 33192)    5   0.19%  98.68%
# [ 33192, 36209)    4   0.15%  98.83%
# [ 36209, 39226)    3   0.11%  98.94%
# [ 39226, 42243)    3   0.11%  99.06%
# [ 42243, 45260)    7   0.26%  99.32%
# [ 45260, 48277)    1   0.04%  99.36%
# [ 48277, 51294)    5   0.19%  99.55%
# [ 51294, 54311)    6   0.23%  99.77%
# [ 54311, 57328)    2   0.08%  99.85%
# [ 57328, 60344]    4   0.15% 100.00%
#
# Attribute in nodes:
# 	358 : DependenceEntropy [NUMERICAL]
# 	341 : LargeDependenceHighGrayLevelEmphasis [NUMERICAL]
# 	281 : HighGrayLevelEmphasis [NUMERICAL]
# 	238 : SmallDependenceHighGrayLevelEmphasis [NUMERICAL]
# 	222 : GrayLevelVariance [NUMERICAL]
# 	214 : SmallDependenceEmphasis [NUMERICAL]
# 	199 : SmallDependenceLowGrayLevelEmphasis [NUMERICAL]
# 	158 : GrayLevelNonUniformity [NUMERICAL]
# 	139 : LargeDependenceLowGrayLevelEmphasis [NUMERICAL]
# 	134 : LowGrayLevelEmphasis [NUMERICAL]
# 	127 : DependenceVariance [NUMERICAL]
# 	64 : LargeDependenceEmphasis [NUMERICAL]
# 	45 : DependenceNonUniformity [NUMERICAL]
# 	41 : DependenceNonUniformityNormalized [NUMERICAL]
#
# Attribute in nodes with depth <= 0:
# 	53 : LargeDependenceHighGrayLevelEmphasis [NUMERICAL]
# 	12 : HighGrayLevelEmphasis [NUMERICAL]
# 	8 : DependenceEntropy [NUMERICAL]
# 	6 : SmallDependenceLowGrayLevelEmphasis [NUMERICAL]
# 	4 : LargeDependenceLowGrayLevelEmphasis [NUMERICAL]
# 	3 : GrayLevelVariance [NUMERICAL]
# 	3 : GrayLevelNonUniformity [NUMERICAL]
# 	1 : LowGrayLevelEmphasis [NUMERICAL]
# 	1 : DependenceVariance [NUMERICAL]
#
# Attribute in nodes with depth <= 1:
# 	74 : LargeDependenceHighGrayLevelEmphasis [NUMERICAL]
# 	37 : HighGrayLevelEmphasis [NUMERICAL]
# 	33 : SmallDependenceEmphasis [NUMERICAL]
# 	33 : DependenceEntropy [NUMERICAL]
# 	22 : SmallDependenceHighGrayLevelEmphasis [NUMERICAL]
# 	19 : GrayLevelNonUniformity [NUMERICAL]
# 	16 : SmallDependenceLowGrayLevelEmphasis [NUMERICAL]
# 	10 : LowGrayLevelEmphasis [NUMERICAL]
# 	9 : GrayLevelVariance [NUMERICAL]
# 	8 : DependenceVariance [NUMERICAL]
# 	7 : LargeDependenceLowGrayLevelEmphasis [NUMERICAL]
# 	3 : LargeDependenceEmphasis [NUMERICAL]
# 	2 : DependenceNonUniformityNormalized [NUMERICAL]
#
# Attribute in nodes with depth <= 2:
# 	113 : LargeDependenceHighGrayLevelEmphasis [NUMERICAL]
# 	85 : HighGrayLevelEmphasis [NUMERICAL]
# 	83 : DependenceEntropy [NUMERICAL]
# 	67 : SmallDependenceEmphasis [NUMERICAL]
# 	56 : SmallDependenceHighGrayLevelEmphasis [NUMERICAL]
# 	41 : GrayLevelVariance [NUMERICAL]
# 	40 : GrayLevelNonUniformity [NUMERICAL]
# 	37 : SmallDependenceLowGrayLevelEmphasis [NUMERICAL]
# 	31 : DependenceVariance [NUMERICAL]
# 	26 : LargeDependenceLowGrayLevelEmphasis [NUMERICAL]
# 	25 : LowGrayLevelEmphasis [NUMERICAL]
# 	15 : LargeDependenceEmphasis [NUMERICAL]
# 	8 : DependenceNonUniformity [NUMERICAL]
# 	4 : DependenceNonUniformityNormalized [NUMERICAL]
#
# Attribute in nodes with depth <= 3:
# 	191 : LargeDependenceHighGrayLevelEmphasis [NUMERICAL]
# 	186 : DependenceEntropy [NUMERICAL]
# 	164 : HighGrayLevelEmphasis [NUMERICAL]
# 	118 : SmallDependenceHighGrayLevelEmphasis [NUMERICAL]
# 	108 : SmallDependenceEmphasis [NUMERICAL]
# 	101 : GrayLevelVariance [NUMERICAL]
# 	96 : SmallDependenceLowGrayLevelEmphasis [NUMERICAL]
# 	83 : GrayLevelNonUniformity [NUMERICAL]
# 	67 : DependenceVariance [NUMERICAL]
# 	62 : LargeDependenceLowGrayLevelEmphasis [NUMERICAL]
# 	61 : LowGrayLevelEmphasis [NUMERICAL]
# 	32 : LargeDependenceEmphasis [NUMERICAL]
# 	26 : DependenceNonUniformity [NUMERICAL]
# 	19 : DependenceNonUniformityNormalized [NUMERICAL]
#
# Attribute in nodes with depth <= 5:
# 	358 : DependenceEntropy [NUMERICAL]
# 	341 : LargeDependenceHighGrayLevelEmphasis [NUMERICAL]
# 	281 : HighGrayLevelEmphasis [NUMERICAL]
# 	238 : SmallDependenceHighGrayLevelEmphasis [NUMERICAL]
# 	222 : GrayLevelVariance [NUMERICAL]
# 	214 : SmallDependenceEmphasis [NUMERICAL]
# 	199 : SmallDependenceLowGrayLevelEmphasis [NUMERICAL]
# 	158 : GrayLevelNonUniformity [NUMERICAL]
# 	139 : LargeDependenceLowGrayLevelEmphasis [NUMERICAL]
# 	134 : LowGrayLevelEmphasis [NUMERICAL]
# 	127 : DependenceVariance [NUMERICAL]
# 	64 : LargeDependenceEmphasis [NUMERICAL]
# 	45 : DependenceNonUniformity [NUMERICAL]
# 	41 : DependenceNonUniformityNormalized [NUMERICAL]
#
# Condition type in nodes:
# 	2561 : HigherCondition
# Condition type in nodes with depth <= 0:
# 	91 : HigherCondition
# Condition type in nodes with depth <= 1:
# 	273 : HigherCondition
# Condition type in nodes with depth <= 2:
# 	631 : HigherCondition
# Condition type in nodes with depth <= 3:
# 	1314 : HigherCondition
# Condition type in nodes with depth <= 5:
# 	2561 : HigherCondition
#
# Training logs:
# Number of iteration to final model: 91
# 	Iter:1 train-loss:1.275531 valid-loss:1.279324  train-accuracy:0.846058 valid-accuracy:0.826896
# 	Iter:2 train-loss:1.185727 valid-loss:1.191519  train-accuracy:0.856960 valid-accuracy:0.841722
# 	Iter:3 train-loss:1.108279 valid-loss:1.113671  train-accuracy:0.861948 valid-accuracy:0.855725
# 	Iter:4 train-loss:1.039371 valid-loss:1.047358  train-accuracy:0.875304 valid-accuracy:0.862709
# 	Iter:5 train-loss:0.980708 valid-loss:0.990444  train-accuracy:0.874769 valid-accuracy:0.863351
# 	Iter:6 train-loss:0.929952 valid-loss:0.941456  train-accuracy:0.875820 valid-accuracy:0.864287
# 	Iter:16 train-loss:0.650554 valid-loss:0.687459  train-accuracy:0.892474 valid-accuracy:0.874002
# 	Iter:26 train-loss:0.545177 valid-loss:0.601408  train-accuracy:0.900861 valid-accuracy:0.881410
# 	Iter:36 train-loss:0.494696 valid-loss:0.568117  train-accuracy:0.906127 valid-accuracy:0.885125
# 	Iter:46 train-loss:0.464291 valid-loss:0.553617  train-accuracy:0.910852 valid-accuracy:0.889170
# 	Iter:56 train-loss:0.440806 valid-loss:0.542969  train-accuracy:0.915200 valid-accuracy:0.890203
# 	Iter:66 train-loss:0.425093 valid-loss:0.539446  train-accuracy:0.918345 valid-accuracy:0.889865
# 	Iter:76 train-loss:0.411955 valid-loss:0.536774  train-accuracy:0.921111 valid-accuracy:0.888639
# 	Iter:86 train-loss:0.400687 valid-loss:0.533262  train-accuracy:0.923194 valid-accuracy:0.890830
# 	Iter:96 train-loss:0.389285 valid-loss:0.533208  train-accuracy:0.925197 valid-accuracy:0.891795
# 	Iter:106 train-loss:0.379510 valid-loss:0.533709  train-accuracy:0.927243 valid-accuracy:0.890568
# 	Iter:116 train-loss:0.370411 valid-loss:0.534045  train-accuracy:0.929237 valid-accuracy:0.889817

# %%
# Model features
model.make_inspector().features()
# Out:
# ["DependenceEntropy" (1; #0),
#  "DependenceNonUniformity" (1; #1),
#  "DependenceNonUniformityNormalized" (1; #2),
#  "DependenceVariance" (1; #3),
#  "GrayLevelNonUniformity" (1; #4),
#  "GrayLevelVariance" (1; #5),
#  "HighGrayLevelEmphasis" (1; #6),
#  "LargeDependenceEmphasis" (1; #7),
#  "LargeDependenceHighGrayLevelEmphasis" (1; #8),
#  "LargeDependenceLowGrayLevelEmphasis" (1; #9),
#  "LowGrayLevelEmphasis" (1; #10),
#  "SmallDependenceEmphasis" (1; #11),
#  "SmallDependenceHighGrayLevelEmphasis" (1; #12),
#  "SmallDependenceLowGrayLevelEmphasis" (1; #13)]

# %%
# Feature importance
model.make_inspector().variable_importances()
# Out:
# {'INV_MEAN_MIN_DEPTH': [("LargeDependenceHighGrayLevelEmphasis" (1; #8),
#    0.3704476387709282),
#   ("DependenceEntropy" (1; #0), 0.23446134123123005),
#   ("HighGrayLevelEmphasis" (1; #6), 0.2252637196273287),
#   ("SmallDependenceEmphasis" (1; #11), 0.20970341813179302),
#   ("SmallDependenceHighGrayLevelEmphasis" (1; #12), 0.20045318296068568),
#   ("SmallDependenceLowGrayLevelEmphasis" (1; #13), 0.19748388790957036),
#   ("GrayLevelNonUniformity" (1; #4), 0.196915960381612),
#   ("GrayLevelVariance" (1; #5), 0.19317064210337273),
#   ("LargeDependenceLowGrayLevelEmphasis" (1; #9), 0.18626848689114534),
#   ("DependenceVariance" (1; #3), 0.1851709673118027),
#   ("LowGrayLevelEmphasis" (1; #10), 0.18294635080600913),
#   ("LargeDependenceEmphasis" (1; #7), 0.17476015375553292),
#   ("DependenceNonUniformity" (1; #1), 0.17258347912772734),
#   ("DependenceNonUniformityNormalized" (1; #2), 0.17237287928893336)],
#  'NUM_AS_ROOT': [("LargeDependenceHighGrayLevelEmphasis" (1; #8), 53.0),
#   ("HighGrayLevelEmphasis" (1; #6), 12.0),
#   ("DependenceEntropy" (1; #0), 8.0),
#   ("SmallDependenceLowGrayLevelEmphasis" (1; #13), 6.0),
#   ("LargeDependenceLowGrayLevelEmphasis" (1; #9), 4.0),
#   ("GrayLevelNonUniformity" (1; #4), 3.0),
#   ("GrayLevelVariance" (1; #5), 3.0),
#   ("DependenceVariance" (1; #3), 1.0),
#   ("LowGrayLevelEmphasis" (1; #10), 1.0)],
#  'SUM_SCORE': [("HighGrayLevelEmphasis" (1; #6), 21609.057603929057),
#   ("LargeDependenceHighGrayLevelEmphasis" (1; #8), 16160.058146215624),
#   ("DependenceEntropy" (1; #0), 11421.726946630924),
#   ("SmallDependenceEmphasis" (1; #11), 8957.047776644089),
#   ("SmallDependenceLowGrayLevelEmphasis" (1; #13), 4396.064254055578),
#   ("LowGrayLevelEmphasis" (1; #10), 2098.6140644381417),
#   ("SmallDependenceHighGrayLevelEmphasis" (1; #12), 1813.9101727410514),
#   ("GrayLevelNonUniformity" (1; #4), 1714.6049349595417),
#   ("DependenceVariance" (1; #3), 1162.1588814009638),
#   ("GrayLevelVariance" (1; #5), 1121.18097493906),
#   ("LargeDependenceLowGrayLevelEmphasis" (1; #9), 975.8495082573651),
#   ("LargeDependenceEmphasis" (1; #7), 639.1909901832861),
#   ("DependenceNonUniformityNormalized" (1; #2), 289.6247128330932),
#   ("DependenceNonUniformity" (1; #1), 217.95655834711087)],
#  'NUM_NODES': [("DependenceEntropy" (1; #0), 358.0),
#   ("LargeDependenceHighGrayLevelEmphasis" (1; #8), 341.0),
#   ("HighGrayLevelEmphasis" (1; #6), 281.0),
#   ("SmallDependenceHighGrayLevelEmphasis" (1; #12), 238.0),
#   ("GrayLevelVariance" (1; #5), 222.0),
#   ("SmallDependenceEmphasis" (1; #11), 214.0),
#   ("SmallDependenceLowGrayLevelEmphasis" (1; #13), 199.0),
#   ("GrayLevelNonUniformity" (1; #4), 158.0),
#   ("LargeDependenceLowGrayLevelEmphasis" (1; #9), 139.0),
#   ("LowGrayLevelEmphasis" (1; #10), 134.0),
#   ("DependenceVariance" (1; #3), 127.0),
#   ("LargeDependenceEmphasis" (1; #7), 64.0),
#   ("DependenceNonUniformity" (1; #1), 45.0),
#   ("DependenceNonUniformityNormalized" (1; #2), 41.0)]}

# %%
# Model self evaluation
model.make_inspector().evaluation()
# Out:
# Evaluation(num_examples=None, accuracy=0.8912434577941895, loss=0.5325760841369629, rmse=None, ndcg=None, aucs=None, auuc=None, qini=None)

# %%
logs = model.make_inspector().training_logs()

plt.figure(figsize=(12, 4))
plt.subplot(1, 2, 1)
plt.plot([log.num_trees for log in logs], [log.evaluation.accuracy for log in logs])
plt.xlabel("Number of trees")
plt.ylabel("Accuracy (out-of-bag)")
plt.subplot(1, 2, 2)
plt.plot([log.num_trees for log in logs], [log.evaluation.loss for log in logs])
plt.xlabel("Number of trees")
plt.ylabel("Logloss (out-of-bag)")
plt.show()

# %% [markdown]
# Calculate the score of our hold-out validation dataset

# %%
predictions = model.predict(val_ds)
y_true      = validation_data["label"]

from sklearn.metrics import roc_auc_score
ROC_AUC = roc_auc_score(y_true, predictions)
print("The ROC AUC score is %.5f" % ROC_AUC )
# Out:
# 12/12 [==============================] - 0s 7ms/step
# The ROC AUC score is 0.95672

# %%
# Compute binary classification metrics with sklearn
import numpy as np
from sklearn.metrics import (
    accuracy_score,
    precision_score,
    recall_score,
    f1_score,
    roc_auc_score,
    average_precision_score,
    confusion_matrix,
    classification_report,
    matthews_corrcoef,
    log_loss,
    brier_score_loss,
)

# Get predictions (probabilities or class labels)
preds = model.predict(test_ds)
# If model outputs probabilities, convert to labels by threshold 0.5
if preds.ndim == 2:
    # For TFDF classification, preds may be class probabilities with shape (N, 2)
    if preds.shape[1] == 2:
        pos_probs = preds[:, 1]
    else:
        # If single-probability column (positive class)
        pos_probs = preds[:, -1]
    y_pred = (pos_probs >= 0.5).astype(int)
else:
    # Already class labels
    y_pred = preds.astype(int)
    pos_probs = None

# Ground truth labels (must be 0/1 integers)
y_true = test_data["label"].astype(int).to_numpy()

# Core metrics
metrics = {}
metrics["accuracy"] = accuracy_score(y_true, y_pred)
metrics["precision"] = precision_score(y_true, y_pred, zero_division=0)
metrics["recall"] = recall_score(y_true, y_pred, zero_division=0)
metrics["f1"] = f1_score(y_true, y_pred, zero_division=0)
metrics["mcc"] = matthews_corrcoef(y_true, y_pred)

# Probabilistic metrics (only if we have probabilities)
if pos_probs is not None:
    metrics["roc_auc"] = roc_auc_score(y_true, pos_probs)
    metrics["pr_auc"] = average_precision_score(y_true, pos_probs)
    metrics["log_loss"] = log_loss(y_true, pos_probs, labels=[0,1])
    metrics["brier_score"] = brier_score_loss(y_true, pos_probs)

# Confusion matrix and detailed report
cm = confusion_matrix(y_true, y_pred, labels=[0,1])
report = classification_report(y_true, y_pred, digits=4)

print("Sklearn binary metrics:")
for k, v in metrics.items():
    print(f"{k}: {v:.4f}")
print("\nConfusion matrix:\n", cm)
print("\nClassification report:\n", report)
# Out:
# 23/23 [==============================] - 0s 6ms/step
# Sklearn binary metrics:
# accuracy: 0.9181
# precision: 0.4680
# recall: 0.8562
# f1: 0.6052
# mcc: 0.5960
# roc_auc: 0.9590
# pr_auc: 0.7935
# log_loss: 0.2123
# brier_score: 0.0610
#
# Confusion matrix:
#  [[19072  1590]
#  [  235  1399]]
#
# Classification report:
#                precision    recall  f1-score   support
#
#            0     0.9878    0.9230    0.9543     20662
#            1     0.4680    0.8562    0.6052      1634
#
#     accuracy                         0.9181     22296
#    macro avg     0.7279    0.8896    0.7798     22296
# weighted avg     0.9497    0.9181    0.9288     22296
