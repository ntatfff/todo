# %%
# Import packages and modules
import numpy  as np
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow_decision_forests as tfdf

from sklearn.model_selection import train_test_split
# Out:
# 2026-05-26 17:45:27.876805: I tensorflow/core/util/port.cc:113] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2026-05-26 17:45:27.910735: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2026-05-26 17:45:28.816423: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
# Check the version of TensorFlow Decision Forests
print("Found TensorFlow Decision Forests v" + tfdf.__version__)
# Out:
# Found TensorFlow Decision Forests v1.9.1

# %%
# train/validation/test = 70/10/20
dataset = pd.read_csv('dataset/glrlm/kernel5-radius5/dataset.csv')

train_data, temp_data = train_test_split(
    dataset, test_size=0.3, random_state=42
 )
validation_data, test_data = train_test_split(
    temp_data, test_size=2/3, random_state=42
 )

# %%
from sklearn.utils.class_weight import compute_class_weight

# tinh class weight tren tap train
classes = np.array([0, 1])
weights = compute_class_weight(class_weight="balanced", classes=classes, y=train_data["label"])
class_weight = {0: weights[0], 1: weights[1]}

# gan sample_weight cho tung dong
train_data["sample_weight"] = train_data["label"].map(class_weight)
validation_data["sample_weight"] = validation_data["label"].map(class_weight)
test_data["sample_weight"] = test_data["label"].map(class_weight)

# Convert the dataset into a TensorFlow dataset.
train_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    train_data, label="label", weight="sample_weight"
)         
val_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    validation_data, label="label", weight="sample_weight"
)
test_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    test_data, label="label", weight="sample_weight"
)
# Out:
# 2026-05-26 17:45:30.643741: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:984] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2026-05-26 17:45:30.644458: W tensorflow/core/common_runtime/gpu/gpu_device.cc:2251] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...

# %%
import keras

# %%
# %%time

# Train a Random Forest model.
model = tfdf.keras.RandomForestModel()

# Add evaluation metrics
model.compile(
    metrics=["accuracy"]
)
model.fit(x=train_ds)

# # Train a Gradient Boosted Trees model.
# model = tfdf.keras.GradientBoostedTreesModel(num_trees=1500)
# model.fit(train_ds)
# Out:
# Use /tmp/tmppiq6ux9n as temporary training directory
# Reading training dataset...
# Training dataset read in 0:00:03.717133. Found 78035 examples.
# Training model...
# [INFO 26-05-26 17:45:44.5851 UTC kernel.cc:1233] Loading model from path /tmp/tmppiq6ux9n/model/ with prefix 527d71dcb4284c34
# Model trained in 0:00:11.266089
# Compiling model...
# [INFO 26-05-26 17:45:45.6826 UTC decision_forest.cc:734] Model loaded with 300 root(s), 692272 node(s), and 16 input feature(s).
# [INFO 26-05-26 17:45:45.6826 UTC abstract_model.cc:1362] Engine "RandomForestOptPred" built
# [INFO 26-05-26 17:45:45.6826 UTC kernel.cc:1061] Use fast generic engine
# Model compiled.
# CPU times: user 1min 41s, sys: 3.34 s, total: 1min 44s
# Wall time: 24.7 s

# %%
# Evaluate the model
evaluate = model.evaluate(val_ds, return_dict=True)
print()

for name, value in evaluate.items():
    print(f"{name}: {value:.4f}")
# Out:
# WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 12/12 [==============================] - 8s 66ms/step - loss: 0.0000e+00 - accuracy: 0.9491
#
# loss: 0.0000
# accuracy: 0.9491

# %%
# Model Summary
model.summary()
# Out:
# Model: "random_forest_model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
# =================================================================
# Total params: 1 (1.00 Byte)
# Trainable params: 0 (0.00 Byte)
# Non-trainable params: 1 (1.00 Byte)
# _________________________________________________________________
# Type: "RANDOM_FOREST"
# Task: CLASSIFICATION
# Label: "__LABEL"
#
# Input Features (16):
# 	GrayLevelNonUniformity
# 	GrayLevelNonUniformityNormalized
# 	GrayLevelVariance
# 	HighGrayLevelRunEmphasis
# 	LongRunEmphasis
# 	LongRunHighGrayLevelEmphasis
# 	LongRunLowGrayLevelEmphasis
# 	LowGrayLevelRunEmphasis
# 	RunEntropy
# 	RunLengthNonUniformity
# 	RunLengthNonUniformityNormalized
# 	RunPercentage
# 	RunVariance
# 	ShortRunEmphasis
# 	ShortRunHighGrayLevelEmphasis
# 	ShortRunLowGrayLevelEmphasis
#
# Trained with weights
#
# Variable Importance: INV_MEAN_MIN_DEPTH:
#     1.     "LongRunHighGrayLevelEmphasis"  0.183836 ################
#     2.         "HighGrayLevelRunEmphasis"  0.154397 ###########
#     3.    "ShortRunHighGrayLevelEmphasis"  0.147108 #########
#     4.          "LowGrayLevelRunEmphasis"  0.118160 #####
#     5.     "ShortRunLowGrayLevelEmphasis"  0.116039 ####
#     6.                       "RunEntropy"  0.115394 ####
#     7. "RunLengthNonUniformityNormalized"  0.111826 ####
#     8.           "GrayLevelNonUniformity"  0.111574 ###
#     9.      "LongRunLowGrayLevelEmphasis"  0.109036 ###
#    10.                 "ShortRunEmphasis"  0.104099 ##
#    11. "GrayLevelNonUniformityNormalized"  0.101472 ##
#    12.                      "RunVariance"  0.091577
#    13.                "GrayLevelVariance"  0.090827
#    14.           "RunLengthNonUniformity"  0.089510
#    15.                    "RunPercentage"  0.088142
#    16.                  "LongRunEmphasis"  0.087654
#
# Variable Importance: NUM_AS_ROOT:
#     1.     "LongRunHighGrayLevelEmphasis" 83.000000 ################
#     2.         "HighGrayLevelRunEmphasis" 74.000000 ##############
#     3.    "ShortRunHighGrayLevelEmphasis" 54.000000 ##########
#     4.     "ShortRunLowGrayLevelEmphasis" 28.000000 #####
#     5.          "LowGrayLevelRunEmphasis" 26.000000 ####
#     6.      "LongRunLowGrayLevelEmphasis" 16.000000 ##
#     7. "GrayLevelNonUniformityNormalized"  9.000000 #
#     8.                       "RunEntropy"  5.000000
#     9.           "GrayLevelNonUniformity"  3.000000
#    10.                    "RunPercentage"  1.000000
#    11.                      "RunVariance"  1.000000
#
# Variable Importance: NUM_NODES:
#     1.                       "RunEntropy" 27280.000000 ################
#     2.     "LongRunHighGrayLevelEmphasis" 27118.000000 ###############
#     3.           "GrayLevelNonUniformity" 27051.000000 ###############
#     4.                "GrayLevelVariance" 25531.000000 #############
#     5. "GrayLevelNonUniformityNormalized" 23571.000000 ##########
#     6.     "ShortRunLowGrayLevelEmphasis" 22288.000000 #########
#     7.    "ShortRunHighGrayLevelEmphasis" 22194.000000 ########
#     8.      "LongRunLowGrayLevelEmphasis" 21811.000000 ########
#     9.         "HighGrayLevelRunEmphasis" 21622.000000 ########
#    10.          "LowGrayLevelRunEmphasis" 20745.000000 ######
#    11.                      "RunVariance" 20040.000000 #####
#    12. "RunLengthNonUniformityNormalized" 18383.000000 ###
#    13.                 "ShortRunEmphasis" 18362.000000 ###
#    14.                  "LongRunEmphasis" 17484.000000 ##
#    15.           "RunLengthNonUniformity" 16653.000000 #
#    16.                    "RunPercentage" 15853.000000
#
# Variable Importance: SUM_SCORE:
#     1.     "LongRunHighGrayLevelEmphasis" 2262734.143621 ################
#     2.         "HighGrayLevelRunEmphasis" 1751967.903929 ###########
#     3.    "ShortRunHighGrayLevelEmphasis" 1516146.113593 #########
#     4.          "LowGrayLevelRunEmphasis" 1039750.396519 #####
#     5.     "ShortRunLowGrayLevelEmphasis" 1013041.517676 #####
#     6.                       "RunEntropy" 961275.955925 #####
#     7.           "GrayLevelNonUniformity" 898184.573065 ####
#     8.      "LongRunLowGrayLevelEmphasis" 849365.369595 ####
#     9. "RunLengthNonUniformityNormalized" 660309.851451 ##
#    10. "GrayLevelNonUniformityNormalized" 612515.212123 ##
#    11.                 "ShortRunEmphasis" 581096.732337 #
#    12.                "GrayLevelVariance" 512413.255799 #
#    13.                      "RunVariance" 464603.573930
#    14.           "RunLengthNonUniformity" 375056.885275
#    15.                  "LongRunEmphasis" 367855.018310
#    16.                    "RunPercentage" 359202.704723
#
#
#
# Winner takes all: true
# Out-of-bag evaluation: accuracy:0.863263 logloss:0.458798
# Number of trees: 300
# Total number of nodes: 692272
#
# Number of nodes by tree:
# Count: 300 Average: 2307.57 StdDev: 119.055
# Min: 1869 Max: 2549 Ignored: 0
# ----------------------------------------------
# [ 1869, 1903)  1   0.33%   0.33%
# [ 1903, 1937)  2   0.67%   1.00%
# [ 1937, 1971)  1   0.33%   1.33%
# [ 1971, 2005)  2   0.67%   2.00%
# [ 2005, 2039)  2   0.67%   2.67%
# [ 2039, 2073)  4   1.33%   4.00% #
# [ 2073, 2107)  6   2.00%   6.00% #
# [ 2107, 2141)  9   3.00%   9.00% ##
# [ 2141, 2175) 10   3.33%  12.33% ##
# [ 2175, 2209) 23   7.67%  20.00% ######
# [ 2209, 2243) 17   5.67%  25.67% ####
# [ 2243, 2277) 27   9.00%  34.67% #######
# [ 2277, 2311) 32  10.67%  45.33% ########
# [ 2311, 2345) 34  11.33%  56.67% ########
# [ 2345, 2379) 34  11.33%  68.00% ########
# [ 2379, 2413) 41  13.67%  81.67% ##########
# [ 2413, 2447) 32  10.67%  92.33% ########
# [ 2447, 2481) 10   3.33%  95.67% ##
# [ 2481, 2515)  7   2.33%  98.00% ##
# [ 2515, 2549]  6   2.00% 100.00% #
#
# Depth by leafs:
# Count: 346286 Average: 12.4191 StdDev: 2.28903
# Min: 3 Max: 15 Ignored: 0
# ----------------------------------------------
# [  3,  4)    10   0.00%   0.00%
# [  4,  5)   288   0.08%   0.09%
# [  5,  6)   975   0.28%   0.37%
# [  6,  7)  2757   0.80%   1.16%
# [  7,  8)  6290   1.82%   2.98% #
# [  8,  9) 12122   3.50%   6.48% #
# [  9, 10) 20171   5.82%  12.31% ##
# [ 10, 11) 29384   8.49%  20.79% ###
# [ 11, 12) 39135  11.30%  32.09% #####
# [ 12, 13) 46860  13.53%  45.62% ######
# [ 13, 14) 51565  14.89%  60.52% ######
# [ 14, 15) 52515  15.17%  75.68% ######
# [ 15, 15] 84214  24.32% 100.00% ##########
#
# Number of training obs by leaf:
# Count: 346286 Average: 67.6045 StdDev: 255.667
# Min: 5 Max: 7625 Ignored: 0
# ----------------------------------------------
# [    5,  386) 334151  96.50%  96.50% ##########
# [  386,  767)   6577   1.90%  98.39%
# [  767, 1148)   2218   0.64%  99.04%
# [ 1148, 1529)   1030   0.30%  99.33%
# [ 1529, 1910)    754   0.22%  99.55%
# [ 1910, 2291)    501   0.14%  99.70%
# [ 2291, 2672)    310   0.09%  99.78%
# [ 2672, 3053)    235   0.07%  99.85%
# [ 3053, 3434)    147   0.04%  99.90%
# [ 3434, 3815)    110   0.03%  99.93%
# [ 3815, 4196)     63   0.02%  99.95%
# [ 4196, 4577)     56   0.02%  99.96%
# [ 4577, 4958)     45   0.01%  99.97%
# [ 4958, 5339)     31   0.01%  99.98%
# [ 5339, 5720)     22   0.01%  99.99%
# [ 5720, 6101)     16   0.00%  99.99%
# [ 6101, 6482)     12   0.00% 100.00%
# [ 6482, 6863)      6   0.00% 100.00%
# [ 6863, 7244)      1   0.00% 100.00%
# [ 7244, 7625]      1   0.00% 100.00%
#
# Attribute in nodes:
# 	27280 : RunEntropy [NUMERICAL]
# 	27118 : LongRunHighGrayLevelEmphasis [NUMERICAL]
# 	27051 : GrayLevelNonUniformity [NUMERICAL]
# 	25531 : GrayLevelVariance [NUMERICAL]
# 	23571 : GrayLevelNonUniformityNormalized [NUMERICAL]
# 	22288 : ShortRunLowGrayLevelEmphasis [NUMERICAL]
# 	22194 : ShortRunHighGrayLevelEmphasis [NUMERICAL]
# 	21811 : LongRunLowGrayLevelEmphasis [NUMERICAL]
# 	21622 : HighGrayLevelRunEmphasis [NUMERICAL]
# 	20745 : LowGrayLevelRunEmphasis [NUMERICAL]
# 	20040 : RunVariance [NUMERICAL]
# 	18383 : RunLengthNonUniformityNormalized [NUMERICAL]
# 	18362 : ShortRunEmphasis [NUMERICAL]
# 	17484 : LongRunEmphasis [NUMERICAL]
# 	16653 : RunLengthNonUniformity [NUMERICAL]
# 	15853 : RunPercentage [NUMERICAL]
#
# Attribute in nodes with depth <= 0:
# 	83 : LongRunHighGrayLevelEmphasis [NUMERICAL]
# 	74 : HighGrayLevelRunEmphasis [NUMERICAL]
# 	54 : ShortRunHighGrayLevelEmphasis [NUMERICAL]
# 	28 : ShortRunLowGrayLevelEmphasis [NUMERICAL]
# 	26 : LowGrayLevelRunEmphasis [NUMERICAL]
# 	16 : LongRunLowGrayLevelEmphasis [NUMERICAL]
# 	9 : GrayLevelNonUniformityNormalized [NUMERICAL]
# 	5 : RunEntropy [NUMERICAL]
# 	3 : GrayLevelNonUniformity [NUMERICAL]
# 	1 : RunVariance [NUMERICAL]
# 	1 : RunPercentage [NUMERICAL]
#
# Attribute in nodes with depth <= 1:
# 	194 : LongRunHighGrayLevelEmphasis [NUMERICAL]
# 	183 : HighGrayLevelRunEmphasis [NUMERICAL]
# 	165 : ShortRunHighGrayLevelEmphasis [NUMERICAL]
# 	74 : ShortRunLowGrayLevelEmphasis [NUMERICAL]
# 	64 : RunLengthNonUniformityNormalized [NUMERICAL]
# 	57 : LowGrayLevelRunEmphasis [NUMERICAL]
# 	48 : LongRunLowGrayLevelEmphasis [NUMERICAL]
# 	45 : ShortRunEmphasis [NUMERICAL]
# 	26 : GrayLevelNonUniformityNormalized [NUMERICAL]
# 	13 : RunLengthNonUniformity [NUMERICAL]
# 	9 : RunEntropy [NUMERICAL]
# 	6 : GrayLevelVariance [NUMERICAL]
# 	5 : GrayLevelNonUniformity [NUMERICAL]
# 	4 : RunVariance [NUMERICAL]
# 	4 : RunPercentage [NUMERICAL]
# 	3 : LongRunEmphasis [NUMERICAL]
#
# Attribute in nodes with depth <= 2:
# 	442 : LongRunHighGrayLevelEmphasis [NUMERICAL]
# 	339 : HighGrayLevelRunEmphasis [NUMERICAL]
# 	297 : ShortRunHighGrayLevelEmphasis [NUMERICAL]
# 	200 : ShortRunLowGrayLevelEmphasis [NUMERICAL]
# 	180 : LowGrayLevelRunEmphasis [NUMERICAL]
# 	137 : LongRunLowGrayLevelEmphasis [NUMERICAL]
# 	92 : RunLengthNonUniformityNormalized [NUMERICAL]
# 	87 : GrayLevelNonUniformity [NUMERICAL]
# 	77 : GrayLevelNonUniformityNormalized [NUMERICAL]
# 	72 : RunEntropy [NUMERICAL]
# 	69 : ShortRunEmphasis [NUMERICAL]
# 	28 : GrayLevelVariance [NUMERICAL]
# 	25 : RunLengthNonUniformity [NUMERICAL]
# 	20 : RunVariance [NUMERICAL]
# 	18 : RunPercentage [NUMERICAL]
# 	17 : LongRunEmphasis [NUMERICAL]
#
# Attribute in nodes with depth <= 3:
# 	817 : LongRunHighGrayLevelEmphasis [NUMERICAL]
# 	526 : HighGrayLevelRunEmphasis [NUMERICAL]
# 	451 : ShortRunHighGrayLevelEmphasis [NUMERICAL]
# 	337 : LowGrayLevelRunEmphasis [NUMERICAL]
# 	315 : ShortRunLowGrayLevelEmphasis [NUMERICAL]
# 	297 : GrayLevelNonUniformity [NUMERICAL]
# 	276 : RunEntropy [NUMERICAL]
# 	266 : LongRunLowGrayLevelEmphasis [NUMERICAL]
# 	225 : GrayLevelNonUniformityNormalized [NUMERICAL]
# 	211 : RunLengthNonUniformityNormalized [NUMERICAL]
# 	176 : ShortRunEmphasis [NUMERICAL]
# 	140 : RunVariance [NUMERICAL]
# 	123 : GrayLevelVariance [NUMERICAL]
# 	120 : RunLengthNonUniformity [NUMERICAL]
# 	113 : LongRunEmphasis [NUMERICAL]
# 	97 : RunPercentage [NUMERICAL]
#
# Attribute in nodes with depth <= 5:
# 	2213 : LongRunHighGrayLevelEmphasis [NUMERICAL]
# 	1507 : RunEntropy [NUMERICAL]
# 	1334 : GrayLevelNonUniformity [NUMERICAL]
# 	1259 : HighGrayLevelRunEmphasis [NUMERICAL]
# 	1176 : LowGrayLevelRunEmphasis [NUMERICAL]
# 	1124 : ShortRunHighGrayLevelEmphasis [NUMERICAL]
# 	1067 : ShortRunLowGrayLevelEmphasis [NUMERICAL]
# 	1007 : LongRunLowGrayLevelEmphasis [NUMERICAL]
# 	932 : GrayLevelNonUniformityNormalized [NUMERICAL]
# 	898 : RunLengthNonUniformityNormalized [NUMERICAL]
# 	837 : GrayLevelVariance [NUMERICAL]
# 	832 : ShortRunEmphasis [NUMERICAL]
# 	820 : RunVariance [NUMERICAL]
# 	697 : RunLengthNonUniformity [NUMERICAL]
# 	645 : RunPercentage [NUMERICAL]
# 	643 : LongRunEmphasis [NUMERICAL]
#
# Condition type in nodes:
# 	345986 : HigherCondition
# Condition type in nodes with depth <= 0:
# 	300 : HigherCondition
# Condition type in nodes with depth <= 1:
# 	900 : HigherCondition
# Condition type in nodes with depth <= 2:
# 	2100 : HigherCondition
# Condition type in nodes with depth <= 3:
# 	4490 : HigherCondition
# Condition type in nodes with depth <= 5:
# 	16991 : HigherCondition
# Node format: NOT_SET
#
# Training OOB:
# 	trees: 1, Out-of-bag evaluation: accuracy:0.834552 logloss:5.96336
# 	trees: 11, Out-of-bag evaluation: accuracy:0.839755 logloss:2.49964
# 	trees: 21, Out-of-bag evaluation: accuracy:0.851627 logloss:1.57566
# 	trees: 31, Out-of-bag evaluation: accuracy:0.85727 logloss:1.2299
# 	trees: 41, Out-of-bag evaluation: accuracy:0.858363 logloss:1.02772
# 	trees: 51, Out-of-bag evaluation: accuracy:0.859155 logloss:0.918373
# 	trees: 61, Out-of-bag evaluation: accuracy:0.860586 logloss:0.840771
# 	trees: 71, Out-of-bag evaluation: accuracy:0.863242 logloss:0.805701
# 	trees: 81, Out-of-bag evaluation: accuracy:0.862429 logloss:0.755217
# 	trees: 91, Out-of-bag evaluation: accuracy:0.863263 logloss:0.718749
# 	trees: 101, Out-of-bag evaluation: accuracy:0.86448 logloss:0.694477
# 	trees: 111, Out-of-bag evaluation: accuracy:0.86401 logloss:0.664765
# 	trees: 121, Out-of-bag evaluation: accuracy:0.864816 logloss:0.629902
# 	trees: 131, Out-of-bag evaluation: accuracy:0.863874 logloss:0.612743
# 	trees: 141, Out-of-bag evaluation: accuracy:0.864118 logloss:0.598257
# 	trees: 152, Out-of-bag evaluation: accuracy:0.863853 logloss:0.583043
# 	trees: 162, Out-of-bag evaluation: accuracy:0.864493 logloss:0.571843
# 	trees: 172, Out-of-bag evaluation: accuracy:0.864341 logloss:0.568116
# 	trees: 182, Out-of-bag evaluation: accuracy:0.86471 logloss:0.552991
# 	trees: 192, Out-of-bag evaluation: accuracy:0.86389 logloss:0.532667
# 	trees: 202, Out-of-bag evaluation: accuracy:0.86389 logloss:0.518443
# 	trees: 212, Out-of-bag evaluation: accuracy:0.862855 logloss:0.507908
# 	trees: 222, Out-of-bag evaluation: accuracy:0.86316 logloss:0.501716
# 	trees: 232, Out-of-bag evaluation: accuracy:0.8633 logloss:0.495811
# 	trees: 242, Out-of-bag evaluation: accuracy:0.863731 logloss:0.490015
# 	trees: 252, Out-of-bag evaluation: accuracy:0.863422 logloss:0.484008
# 	trees: 262, Out-of-bag evaluation: accuracy:0.863295 logloss:0.483889
# 	trees: 272, Out-of-bag evaluation: accuracy:0.863295 logloss:0.47813
# 	trees: 282, Out-of-bag evaluation: accuracy:0.863848 logloss:0.469833
# 	trees: 292, Out-of-bag evaluation: accuracy:0.863554 logloss:0.464326
# 	trees: 300, Out-of-bag evaluation: accuracy:0.863263 logloss:0.458798

# %%
# Model features
model.make_inspector().features()
# Out:
# ["GrayLevelNonUniformity" (1; #0),
#  "GrayLevelNonUniformityNormalized" (1; #1),
#  "GrayLevelVariance" (1; #2),
#  "HighGrayLevelRunEmphasis" (1; #3),
#  "LongRunEmphasis" (1; #4),
#  "LongRunHighGrayLevelEmphasis" (1; #5),
#  "LongRunLowGrayLevelEmphasis" (1; #6),
#  "LowGrayLevelRunEmphasis" (1; #7),
#  "RunEntropy" (1; #8),
#  "RunLengthNonUniformity" (1; #9),
#  "RunLengthNonUniformityNormalized" (1; #10),
#  "RunPercentage" (1; #11),
#  "RunVariance" (1; #12),
#  "ShortRunEmphasis" (1; #13),
#  "ShortRunHighGrayLevelEmphasis" (1; #14),
#  "ShortRunLowGrayLevelEmphasis" (1; #15)]

# %%
# Feature importance
model.make_inspector().variable_importances()
# Out:
# {'INV_MEAN_MIN_DEPTH': [("LongRunHighGrayLevelEmphasis" (1; #5),
#    0.18383624935401874),
#   ("HighGrayLevelRunEmphasis" (1; #3), 0.15439735579287753),
#   ("ShortRunHighGrayLevelEmphasis" (1; #14), 0.14710820156078594),
#   ("LowGrayLevelRunEmphasis" (1; #7), 0.11816034225610401),
#   ("ShortRunLowGrayLevelEmphasis" (1; #15), 0.11603915779033733),
#   ("RunEntropy" (1; #8), 0.11539433479178947),
#   ("RunLengthNonUniformityNormalized" (1; #10), 0.11182565678735377),
#   ("GrayLevelNonUniformity" (1; #0), 0.11157404208301415),
#   ("LongRunLowGrayLevelEmphasis" (1; #6), 0.10903583975842031),
#   ("ShortRunEmphasis" (1; #13), 0.10409948327408117),
#   ("GrayLevelNonUniformityNormalized" (1; #1), 0.10147239759930529),
#   ("RunVariance" (1; #12), 0.09157693777491478),
#   ("GrayLevelVariance" (1; #2), 0.09082706147368269),
#   ("RunLengthNonUniformity" (1; #9), 0.08951022221705156),
#   ("RunPercentage" (1; #11), 0.08814209150641472),
#   ("LongRunEmphasis" (1; #4), 0.08765354280330874)],
#  'SUM_SCORE': [("LongRunHighGrayLevelEmphasis" (1; #5), 2262734.1436211066),
#   ("HighGrayLevelRunEmphasis" (1; #3), 1751967.903928871),
#   ("ShortRunHighGrayLevelEmphasis" (1; #14), 1516146.113593192),
#   ("LowGrayLevelRunEmphasis" (1; #7), 1039750.3965189909),
#   ("ShortRunLowGrayLevelEmphasis" (1; #15), 1013041.5176756032),
#   ("RunEntropy" (1; #8), 961275.9559250021),
#   ("GrayLevelNonUniformity" (1; #0), 898184.5730654976),
#   ("LongRunLowGrayLevelEmphasis" (1; #6), 849365.369595316),
#   ("RunLengthNonUniformityNormalized" (1; #10), 660309.8514508094),
#   ("GrayLevelNonUniformityNormalized" (1; #1), 612515.212122985),
#   ("ShortRunEmphasis" (1; #13), 581096.7323374463),
#   ("GrayLevelVariance" (1; #2), 512413.2557993851),
#   ("RunVariance" (1; #12), 464603.57393045496),
#   ("RunLengthNonUniformity" (1; #9), 375056.885274923),
#   ("LongRunEmphasis" (1; #4), 367855.018309729),
#   ("RunPercentage" (1; #11), 359202.7047227774)],
#  'NUM_AS_ROOT': [("LongRunHighGrayLevelEmphasis" (1; #5), 83.0),
#   ("HighGrayLevelRunEmphasis" (1; #3), 74.0),
#   ("ShortRunHighGrayLevelEmphasis" (1; #14), 54.0),
#   ("ShortRunLowGrayLevelEmphasis" (1; #15), 28.0),
#   ("LowGrayLevelRunEmphasis" (1; #7), 26.0),
#   ("LongRunLowGrayLevelEmphasis" (1; #6), 16.0),
#   ("GrayLevelNonUniformityNormalized" (1; #1), 9.0),
#   ("RunEntropy" (1; #8), 5.0),
#   ("GrayLevelNonUniformity" (1; #0), 3.0),
#   ("RunPercentage" (1; #11), 1.0),
#   ("RunVariance" (1; #12), 1.0)],
#  'NUM_NODES': [("RunEntropy" (1; #8), 27280.0),
#   ("LongRunHighGrayLevelEmphasis" (1; #5), 27118.0),
#   ("GrayLevelNonUniformity" (1; #0), 27051.0),
#   ("GrayLevelVariance" (1; #2), 25531.0),
#   ("GrayLevelNonUniformityNormalized" (1; #1), 23571.0),
#   ("ShortRunLowGrayLevelEmphasis" (1; #15), 22288.0),
#   ("ShortRunHighGrayLevelEmphasis" (1; #14), 22194.0),
#   ("LongRunLowGrayLevelEmphasis" (1; #6), 21811.0),
#   ("HighGrayLevelRunEmphasis" (1; #3), 21622.0),
#   ("LowGrayLevelRunEmphasis" (1; #7), 20745.0),
#   ("RunVariance" (1; #12), 20040.0),
#   ("RunLengthNonUniformityNormalized" (1; #10), 18383.0),
#   ("ShortRunEmphasis" (1; #13), 18362.0),
#   ("LongRunEmphasis" (1; #4), 17484.0),
#   ("RunLengthNonUniformity" (1; #9), 16653.0),
#   ("RunPercentage" (1; #11), 15853.0)]}

# %%
# Model self evaluation
model.make_inspector().evaluation()
# Out:
# Evaluation(num_examples=78035, accuracy=0.8632632104273721, loss=0.45879760219104837, rmse=None, ndcg=None, aucs=None, auuc=None, qini=None)

# %%
logs = model.make_inspector().training_logs()

plt.figure(figsize=(12, 4))
plt.subplot(1, 2, 1)
plt.plot([log.num_trees for log in logs], [log.evaluation.accuracy for log in logs])
plt.xlabel("Number of trees")
plt.ylabel("Accuracy (out-of-bag)")
plt.subplot(1, 2, 2)
plt.plot([log.num_trees for log in logs], [log.evaluation.loss for log in logs])
plt.xlabel("Number of trees")
plt.ylabel("Logloss (out-of-bag)")
plt.show()

# %% [markdown]
# Calculate the score of our hold-out validation dataset

# %%
predictions = model.predict(val_ds)
y_true      = validation_data["label"]

from sklearn.metrics import roc_auc_score
ROC_AUC = roc_auc_score(y_true, predictions)
print("The ROC AUC score is %.5f" % ROC_AUC )
# Out:
# 12/12 [==============================] - 1s 81ms/step
# The ROC AUC score is 0.96053

# %%
# Compute binary classification metrics with sklearn
import numpy as np
from sklearn.metrics import (
    accuracy_score,
    precision_score,
    recall_score,
    f1_score,
    roc_auc_score,
    average_precision_score,
    confusion_matrix,
    classification_report,
    matthews_corrcoef,
    log_loss,
    brier_score_loss,
)

# Get predictions (probabilities or class labels)
preds = model.predict(test_ds)
# If model outputs probabilities, convert to labels by threshold 0.5
if preds.ndim == 2:
    # For TFDF classification, preds may be class probabilities with shape (N, 2)
    if preds.shape[1] == 2:
        pos_probs = preds[:, 1]
    else:
        # If single-probability column (positive class)
        pos_probs = preds[:, -1]
    y_pred = (pos_probs >= 0.5).astype(int)
else:
    # Already class labels
    y_pred = preds.astype(int)
    pos_probs = None

# Ground truth labels (must be 0/1 integers)
y_true = test_data["label"].astype(int).to_numpy()

# Core metrics
metrics = {}
metrics["accuracy"] = accuracy_score(y_true, y_pred)
metrics["precision"] = precision_score(y_true, y_pred, zero_division=0)
metrics["recall"] = recall_score(y_true, y_pred, zero_division=0)
metrics["f1"] = f1_score(y_true, y_pred, zero_division=0)
metrics["mcc"] = matthews_corrcoef(y_true, y_pred)

# Probabilistic metrics (only if we have probabilities)
if pos_probs is not None:
    metrics["roc_auc"] = roc_auc_score(y_true, pos_probs)
    metrics["pr_auc"] = average_precision_score(y_true, pos_probs)
    metrics["log_loss"] = log_loss(y_true, pos_probs, labels=[0,1])
    metrics["brier_score"] = brier_score_loss(y_true, pos_probs)

# Confusion matrix and detailed report
cm = confusion_matrix(y_true, y_pred, labels=[0,1])
report = classification_report(y_true, y_pred, digits=4)

print("Sklearn binary metrics:")
for k, v in metrics.items():
    print(f"{k}: {v:.4f}")
print("\nConfusion matrix:\n", cm)
print("\nClassification report:\n", report)
# Out:
# 23/23 [==============================] - 1s 32ms/step
# Sklearn binary metrics:
# accuracy: 0.9518
# precision: 0.6303
# recall: 0.7676
# f1: 0.6922
# mcc: 0.6702
# roc_auc: 0.9619
# pr_auc: 0.7987
# log_loss: 0.1325
# brier_score: 0.0369
#
# Confusion matrix:
#  [[20012   709]
#  [  366  1209]]
#
# Classification report:
#                precision    recall  f1-score   support
#
#            0     0.9820    0.9658    0.9738     20721
#            1     0.6303    0.7676    0.6922      1575
#
#     accuracy                         0.9518     22296
#    macro avg     0.8062    0.8667    0.8330     22296
# weighted avg     0.9572    0.9518    0.9540     22296
