# %%
# Import packages and modules
import numpy  as np
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow_decision_forests as tfdf

from sklearn.model_selection import train_test_split
# Out:
# 2025-12-19 17:57:57.664050: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-12-19 17:57:57.667680: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:32] Could not find cuda drivers on your machine, GPU will not be used.
# 2025-12-19 17:57:57.702356: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:32] Could not find cuda drivers on your machine, GPU will not be used.
# 2025-12-19 17:57:57.719852: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1766167077.736990   37899 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1766167077.742144   37899 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1766167077.765141   37899 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1766167077.765164   37899 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1766167077.765166   37899 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1766167077.765167   37899 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# 2025-12-19 17:57:57.770628: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# <p style="margin:0px;">🌲 Try <a href="https://ydf.readthedocs.io/en/latest/" target="_blank">YDF</a>, the successor of
#     <a href="https://www.tensorflow.org/decision_forests" target="_blank">TensorFlow
#         Decision Forests</a> using the same algorithms but with more features and faster
#     training!
# </p>
# <div style="display: flex; flex-wrap: wrap; margin:5px;max-width: 880px;">
#     <div style="flex: 1; border-radius: 10px; background-color: F0F0F0; padding: 5px;">
#         <p
#             style="font-weight: bold; margin:0px;text-align: center;border-bottom: 1px solid #C0C0C0;margin-bottom: 4px;">
#             Old code</p>
#         <pre style="overflow-wrap: anywhere; overflow: auto; margin:0px;font-size: 9pt;">
# import tensorflow_decision_forests as tfdf
#
# tf_ds = tfdf.keras.pd_dataframe_to_tf_dataset(ds, label="l")
# model = tfdf.keras.RandomForestModel(label="l")
# model.fit(tf_ds)
# </pre>
#     </div>
#     <div style="width: 5px;"></div>
#     <div style="flex: 1; border-radius: 10px; background-color: F0F0F0; padding: 5px;">
#         <p
#             style="font-weight: bold; margin:0px;text-align: center;border-bottom: 1px solid #C0C0C0;margin-bottom: 4px;">
#             New code</p>
#         <pre style="overflow-wrap: anywhere; overflow: auto; margin:0px;font-size: 9pt;">
# import ydf
#
# model = ydf.RandomForestLearner(label="l").train(ds)
# </pre>
#     </div>
# </div>
# <p style="margin:0px;font-size: 9pt;">(Learn more in the <a
#         href="https://ydf.readthedocs.io/en/latest/tutorial/migrating_to_ydf/" target="_blank">migration
#         guide</a>)</p>

# %%
# Check the version of TensorFlow Decision Forests
print("Found TensorFlow Decision Forests v" + tfdf.__version__)
# Out:
# Found TensorFlow Decision Forests v1.12.0

# %%
# train/validation = 80/20
dataset = pd.read_csv('dataset/glrlm/kernel5-radius5/dataset.csv')
train_data, validation_data = train_test_split(
    dataset, test_size=0.2, random_state=42
)

# %%
# Convert the dataset into a TensorFlow dataset.
train_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    train_data, label="label"
)         
val_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    validation_data, label="label"
)
# Out:
# E0000 00:00:1766167080.364610   37899 cuda_executor.cc:1228] INTERNAL: CUDA Runtime error: Failed call to cudaGetRuntimeVersion: Error loading CUDA libraries. GPU will not be used.: Error loading CUDA libraries. GPU will not be used.
# W0000 00:00:1766167080.365271   37899 gpu_device.cc:2341] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...

# %%
import keras

# %%
# %%time

# Train a Random Forest model.
model = tfdf.keras.RandomForestModel()

# Add evaluation metrics
model.compile(
    metrics=["accuracy"]
)
model.fit(x=train_ds)

# # Train a Gradient Boosted Trees model.
# model = tfdf.keras.GradientBoostedTreesModel(num_trees=1500)
# model.fit(train_ds)
# Out:
# Use /tmp/tmph5ojsx91 as temporary training directory
# Reading training dataset...
# Training dataset read in 0:00:02.637867. Found 89183 examples.
# Training model...
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1766167083.147736   37899 kernel.cc:782] Start Yggdrasil model training
# I0000 00:00:1766167083.147808   37899 kernel.cc:783] Collect training examples
# I0000 00:00:1766167083.147830   37899 kernel.cc:795] Dataspec guide:
# column_guides {
#   column_name_pattern: "^__LABEL$"
#   type: CATEGORICAL
#   categorial {
#     min_vocab_frequency: 0
#     max_vocab_count: -1
#   }
# }
# default_column_guide {
#   categorial {
#     max_vocab_count: 2000
#   }
#   discretized_numerical {
#     maximum_num_bins: 255
#   }
# }
# ignore_columns_without_guides: false
# detect_numerical_as_discretized_numerical: false
#
# I0000 00:00:1766167083.148134   37899 kernel.cc:401] Number of batches: 90
# I0000 00:00:1766167083.148156   37899 kernel.cc:402] Number of examples: 89183
# I0000 00:00:1766167083.152989   37899 kernel.cc:802] Training dataset:
# Number of records: 89183
# Number of columns: 17
#
# Number of columns by type:
# 	NUMERICAL: 16 (94.1176%)
# 	CATEGORICAL: 1 (5.88235%)
#
# Columns:
#
# NUMERICAL: 16 (94.1176%)
# 	0: "GrayLevelNonUniformity" NUMERICAL mean:86.0575 min:11.1848 max:316.483 sd:59.4622
# 	1: "GrayLevelNonUniformityNormalized" NUMERICAL mean:0.0994887 min:0.00862101 max:0.906457 sd:0.100403
# 	2: "GrayLevelVariance" NUMERICAL mean:122.748 min:0.0467717 max:3026.75 sd:179.378
# 	3: "HighGrayLevelRunEmphasis" NUMERICAL mean:1620.33 min:2.30469 max:20672.7 sd:1697.34
# 	4: "LongRunEmphasis" NUMERICAL mean:2.96626 min:1.05608 max:48.0937 sd:2.77264
# 	5: "LongRunHighGrayLevelEmphasis" NUMERICAL mean:2186.73 min:17.2386 max:32239.5 sd:2061.88
# 	6: "LongRunLowGrayLevelEmphasis" NUMERICAL mean:0.565386 min:6.62884e-05 max:24.8604 sd:1.33673
# 	7: "LowGrayLevelRunEmphasis" NUMERICAL mean:0.041284 min:5.03937e-05 max:0.748973 sd:0.0696042
# 	8: "RunEntropy" NUMERICAL mean:4.96991 min:2.90909 max:7.14205 sd:0.750989
# 	9: "RunLengthNonUniformity" NUMERICAL mean:794.027 min:45.4568 max:1260.19 sd:319.66
# 	10: "RunLengthNonUniformityNormalized" NUMERICAL mean:0.710277 min:0.164866 max:0.964275 sd:0.194697
# 	11: "RunPercentage" NUMERICAL mean:0.791498 min:0.189505 max:0.981853 sd:0.164444
# 	12: "RunVariance" NUMERICAL mean:0.856234 min:0.0187296 max:10.5406 sd:1.16363
# 	13: "ShortRunEmphasis" NUMERICAL mean:0.846985 min:0.200989 max:0.986308 sd:0.132533
# 	14: "ShortRunHighGrayLevelEmphasis" NUMERICAL mean:1520.95 min:0.664016 max:18643.6 sd:1618.17
# 	15: "ShortRunLowGrayLevelEmphasis" NUMERICAL mean:0.0182489 min:4.70329e-05 max:0.304712 sd:0.0268343
#
# CATEGORICAL: 1 (5.88235%)
# 	16: "__LABEL" CATEGORICAL integerized vocab-size:3 no-ood-item
#
# Terminology:
# 	nas: Number of non-available (i.e. missing) values.
# 	ood: Out of dictionary.
# 	manually-defined: Attribute whose type is manually defined by the user, i.e., the type was not automatically inferred.
# 	tokenized: The attribute value is obtained through tokenization.
# 	has-dict: The attribute is attached to a string dictionary e.g. a categorical attribute stored as a string.
# 	vocab-size: Number of unique values.
#
# I0000 00:00:1766167083.153033   37899 kernel.cc:818] Configure learner
# I0000 00:00:1766167083.153143   37899 kernel.cc:831] Training config:
# learner: "RANDOM_FOREST"
# features: "^GrayLevelNonUniformity$"
# features: "^GrayLevelNonUniformityNormalized$"
# features: "^GrayLevelVariance$"
# features: "^HighGrayLevelRunEmphasis$"
# features: "^LongRunEmphasis$"
# features: "^LongRunHighGrayLevelEmphasis$"
# features: "^LongRunLowGrayLevelEmphasis$"
# features: "^LowGrayLevelRunEmphasis$"
# features: "^RunEntropy$"
# features: "^RunLengthNonUniformity$"
# features: "^RunLengthNonUniformityNormalized$"
# features: "^RunPercentage$"
# features: "^RunVariance$"
# features: "^ShortRunEmphasis$"
# features: "^ShortRunHighGrayLevelEmphasis$"
# features: "^ShortRunLowGrayLevelEmphasis$"
# label: "^__LABEL$"
# task: CLASSIFICATION
# random_seed: 123456
# metadata {
#   framework: "TF Keras"
# }
# pure_serving_model: false
# [yggdrasil_decision_forests.model.random_forest.proto.random_forest_config] {
#   num_trees: 300
#   decision_tree {
#     max_depth: 16
#     min_examples: 5
#     in_split_min_examples_check: true
#     keep_non_leaf_label_distribution: true
#     num_candidate_attributes: 0
#     missing_value_policy: GLOBAL_IMPUTATION
#     allow_na_conditions: false
#     categorical_set_greedy_forward {
#       sampling: 0.1
#       max_num_items: -1
#       min_item_frequency: 1
#     }
#     growing_strategy_local {
#     }
#     categorical {
#       cart {
#       }
#     }
#     axis_aligned_split {
#     }
#     internal {
#       sorting_strategy: PRESORTED
#     }
#     uplift {
#       min_examples_in_treatment: 5
#       split_score: KULLBACK_LEIBLER
#     }
#     numerical_vector_sequence {
#       max_num_test_examples: 1000
#       num_random_selected_anchors: 100
#     }
#   }
#   winner_take_all_inference: true
#   compute_oob_performances: true
#   compute_oob_variable_importances: false
#   num_oob_variable_importances_permutations: 1
#   bootstrap_training_dataset: true
#   bootstrap_size_ratio: 1
#   adapt_bootstrap_size_ratio_for_maximum_training_duration: false
#   sampling_with_replacement: true
# }
#
# I0000 00:00:1766167083.153338   37899 kernel.cc:834] Deployment config:
# cache_path: "/tmp/tmph5ojsx91/working_cache"
# num_threads: 12
# try_resume_training: true
#
# I0000 00:00:1766167083.153494   37995 kernel.cc:895] Train model
# I0000 00:00:1766167083.153673   37995 random_forest.cc:438] Training random forest on 89183 example(s) and 16 feature(s).
# I0000 00:00:1766167083.171185   37995 gpu.cc:93] Cannot initialize GPU: Not compiled with GPU support
# I0000 00:00:1766167083.955325   38016 random_forest.cc:865] Train tree 1/300 accuracy:0.94846 logloss:1.85769 [index:9 total:0.78s tree:0.78s]
# I0000 00:00:1766167086.852205   38008 random_forest.cc:865] Train tree 11/300 accuracy:0.959223 logloss:0.803162 [index:1 total:3.68s tree:3.68s]
# I0000 00:00:1766167087.125734   38008 random_forest.cc:865] Train tree 21/300 accuracy:0.961042 logloss:0.561722 [index:22 total:3.95s tree:0.27s]
# I0000 00:00:1766167087.384676   38019 random_forest.cc:865] Train tree 31/300 accuracy:0.961316 logloss:0.467155 [index:30 total:4.21s tree:0.29s]
# I0000 00:00:1766167087.680847   38009 random_forest.cc:865] Train tree 41/300 accuracy:0.961943 logloss:0.409317 [index:40 total:4.51s tree:0.32s]
# I0000 00:00:1766167087.921213   38013 random_forest.cc:865] Train tree 51/300 accuracy:0.962022 logloss:0.377892 [index:50 total:4.75s tree:0.28s]
# I0000 00:00:1766167088.145437   38018 random_forest.cc:865] Train tree 61/300 accuracy:0.962313 logloss:0.348143 [index:61 total:4.97s tree:0.27s]
# I0000 00:00:1766167088.342638   38017 random_forest.cc:865] Train tree 71/300 accuracy:0.96237 logloss:0.327346 [index:71 total:5.17s tree:0.27s]
# I0000 00:00:1766167088.603579   38014 random_forest.cc:865] Train tree 81/300 accuracy:0.962482 logloss:0.312425 [index:79 total:5.43s tree:0.30s]
# I0000 00:00:1766167088.851854   38019 random_forest.cc:865] Train tree 91/300 accuracy:0.962683 logloss:0.301708 [index:90 total:5.68s tree:0.28s]
# I0000 00:00:1766167089.068356   38011 random_forest.cc:865] Train tree 101/300 accuracy:0.96274 logloss:0.292972 [index:100 total:5.89s tree:0.28s]
# I0000 00:00:1766167089.315175   38012 random_forest.cc:865] Train tree 111/300 accuracy:0.962908 logloss:0.281809 [index:111 total:6.14s tree:0.27s]
# I0000 00:00:1766167089.559017   38018 random_forest.cc:865] Train tree 121/300 accuracy:0.962863 logloss:0.272362 [index:120 total:6.38s tree:0.28s]
# I0000 00:00:1766167089.817561   38014 random_forest.cc:865] Train tree 131/300 accuracy:0.962964 logloss:0.264468 [index:129 total:6.64s tree:0.35s]
# I0000 00:00:1766167090.063375   38015 random_forest.cc:865] Train tree 141/300 accuracy:0.962941 logloss:0.257525 [index:141 total:6.89s tree:0.27s]
# I0000 00:00:1766167090.294221   38008 random_forest.cc:865] Train tree 151/300 accuracy:0.962953 logloss:0.248104 [index:150 total:7.12s tree:0.28s]
# I0000 00:00:1766167090.496998   38011 random_forest.cc:865] Train tree 161/300 accuracy:0.962818 logloss:0.244506 [index:160 total:7.32s tree:0.28s]
# I0000 00:00:1766167090.717039   38012 random_forest.cc:865] Train tree 171/300 accuracy:0.963042 logloss:0.239085 [index:170 total:7.54s tree:0.27s]
# I0000 00:00:1766167090.985160   38019 random_forest.cc:865] Train tree 181/300 accuracy:0.963132 logloss:0.234511 [index:178 total:7.81s tree:0.31s]
# I0000 00:00:1766167091.243893   38014 random_forest.cc:865] Train tree 191/300 accuracy:0.96311 logloss:0.231709 [index:189 total:8.07s tree:0.29s]
# I0000 00:00:1766167091.544263   38015 random_forest.cc:865] Train tree 201/300 accuracy:0.963087 logloss:0.227779 [index:200 total:8.37s tree:0.37s]
# I0000 00:00:1766167091.758264   38008 random_forest.cc:865] Train tree 211/300 accuracy:0.963121 logloss:0.225642 [index:211 total:8.58s tree:0.31s]
# I0000 00:00:1766167091.952790   38011 random_forest.cc:865] Train tree 221/300 accuracy:0.962986 logloss:0.221421 [index:220 total:8.78s tree:0.28s]
# I0000 00:00:1766167092.219968   38017 random_forest.cc:865] Train tree 231/300 accuracy:0.963031 logloss:0.217116 [index:228 total:9.04s tree:0.30s]
# I0000 00:00:1766167092.485492   38013 random_forest.cc:865] Train tree 241/300 accuracy:0.963042 logloss:0.215981 [index:241 total:9.31s tree:0.28s]
# I0000 00:00:1766167092.724957   38015 random_forest.cc:865] Train tree 251/300 accuracy:0.963054 logloss:0.212506 [index:249 total:9.55s tree:0.30s]
# I0000 00:00:1766167092.951500   38016 random_forest.cc:865] Train tree 261/300 accuracy:0.963087 logloss:0.211078 [index:260 total:9.78s tree:0.27s]
# I0000 00:00:1766167093.178687   38008 random_forest.cc:865] Train tree 271/300 accuracy:0.963199 logloss:0.209977 [index:270 total:10.00s tree:0.29s]
# I0000 00:00:1766167093.389172   38014 random_forest.cc:865] Train tree 281/300 accuracy:0.963177 logloss:0.20859 [index:280 total:10.21s tree:0.29s]
# I0000 00:00:1766167093.639507   38019 random_forest.cc:865] Train tree 291/300 accuracy:0.963121 logloss:0.206882 [index:290 total:10.46s tree:0.28s]
# I0000 00:00:1766167093.843743   38015 random_forest.cc:865] Train tree 300/300 accuracy:0.963087 logloss:0.20518 [index:299 total:10.67s tree:0.25s]
# I0000 00:00:1766167093.843969   37995 random_forest.cc:949] Final OOB metrics: accuracy:0.963087 logloss:0.20518
# I0000 00:00:1766167094.003087   37995 kernel.cc:926] Export model in log directory: /tmp/tmph5ojsx91 with prefix 604b0da55e67490e
# I0000 00:00:1766167094.260318   37995 kernel.cc:944] Save model in resources
# I0000 00:00:1766167094.266144   37899 abstract_model.cc:921] Model self evaluation:
# Number of predictions (without weights): 89183
# Number of predictions (with weights): 89183
# Task: CLASSIFICATION
# Label: __LABEL
#
# Accuracy: 0.963087  CI95[W][0.962032 0.96412]
# LogLoss: : 0.20518
# ErrorRate: : 0.0369129
#
# Default Accuracy: : 0.927127
# Default LogLoss: : 0.261007
# Default ErrorRate: : 0.0728726
#
# Confusion Table:
# truth\prediction
#        1     2
# 1  82028   656
# 2   2636  3863
# Total: 89183
#
#
# 2025-12-19 17:58:14.363438: I tensorflow_decision_forests/tensorflow/ops/inference/kernel.cc:1206] Loading model from path /tmp/tmph5ojsx91/model/ with prefix 604b0da55e67490e
# Model trained in 0:00:12.236481
# Compiling model...
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1766167095.250788   37899 decision_forest.cc:808] Model loaded with 300 root(s), 748112 node(s), and 16 input feature(s).
# I0000 00:00:1766167095.254123   37899 abstract_model.cc:1439] Engine "RandomForestOptPred" built
# 2025-12-19 17:58:15.254182: I tensorflow_decision_forests/tensorflow/ops/inference/kernel.cc:1035] Use fast generic engine
# Model compiled.
# CPU times: user 1min 38s, sys: 1.57 s, total: 1min 40s
# Wall time: 15.6 s

# %%
# Evaluate the model
evaluate = model.evaluate(val_ds, return_dict=True)
print()

for name, value in evaluate.items():
    print(f"{name}: {value:.4f}")
# Out:
# 23/23 [==============================] - 1s 29ms/step - loss: 0.0000e+00 - accuracy: 0.9643
#
# loss: 0.0000
# accuracy: 0.9643

# %%
# Model Summary
model.summary()
# Out:
# Model: "random_forest_model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
# =================================================================
# Total params: 1 (1.00 Byte)
# Trainable params: 0 (0.00 Byte)
# Non-trainable params: 1 (1.00 Byte)
# _________________________________________________________________
# Type: "RANDOM_FOREST"
# Task: CLASSIFICATION
# Label: "__LABEL"
#
# Input Features (16):
# 	GrayLevelNonUniformity
# 	GrayLevelNonUniformityNormalized
# 	GrayLevelVariance
# 	HighGrayLevelRunEmphasis
# 	LongRunEmphasis
# 	LongRunHighGrayLevelEmphasis
# 	LongRunLowGrayLevelEmphasis
# 	LowGrayLevelRunEmphasis
# 	RunEntropy
# 	RunLengthNonUniformity
# 	RunLengthNonUniformityNormalized
# 	RunPercentage
# 	RunVariance
# 	ShortRunEmphasis
# 	ShortRunHighGrayLevelEmphasis
# 	ShortRunLowGrayLevelEmphasis
#
# No weights
#
# Variable Importance: INV_MEAN_MIN_DEPTH:
#     1.     "LongRunHighGrayLevelEmphasis"  0.224497 ################
#     2.         "HighGrayLevelRunEmphasis"  0.141199 ######
#     3.    "ShortRunHighGrayLevelEmphasis"  0.137459 #####
#     4.          "LowGrayLevelRunEmphasis"  0.116266 ###
#     5.           "GrayLevelNonUniformity"  0.115740 ###
#     6.     "ShortRunLowGrayLevelEmphasis"  0.115394 ###
#     7.      "LongRunLowGrayLevelEmphasis"  0.112266 ###
#     8.                       "RunEntropy"  0.108218 ##
#     9. "RunLengthNonUniformityNormalized"  0.105549 ##
#    10.                 "ShortRunEmphasis"  0.102262 #
#    11. "GrayLevelNonUniformityNormalized"  0.099392 #
#    12.                      "RunVariance"  0.091605
#    13.                "GrayLevelVariance"  0.088954
#    14.           "RunLengthNonUniformity"  0.087078
#    15.                  "LongRunEmphasis"  0.086770
#    16.                    "RunPercentage"  0.085678
#
# Variable Importance: NUM_AS_ROOT:
#     1.     "LongRunHighGrayLevelEmphasis" 96.000000 ################
#     2.    "ShortRunHighGrayLevelEmphasis" 58.000000 #########
#     3.         "HighGrayLevelRunEmphasis" 49.000000 ########
#     4.     "ShortRunLowGrayLevelEmphasis" 35.000000 #####
#     5.          "LowGrayLevelRunEmphasis" 26.000000 ####
#     6.      "LongRunLowGrayLevelEmphasis" 17.000000 ##
#     7. "GrayLevelNonUniformityNormalized"  9.000000 #
#     8.           "GrayLevelNonUniformity"  6.000000
#     9.                  "LongRunEmphasis"  2.000000
#    10.                      "RunVariance"  2.000000
#
# Variable Importance: NUM_NODES:
#     1.           "GrayLevelNonUniformity" 29775.000000 ################
#     2.     "LongRunHighGrayLevelEmphasis" 29305.000000 ###############
#     3.                       "RunEntropy" 28717.000000 ##############
#     4.                "GrayLevelVariance" 27250.000000 ############
#     5. "GrayLevelNonUniformityNormalized" 25426.000000 ##########
#     6.     "ShortRunLowGrayLevelEmphasis" 24326.000000 ########
#     7.    "ShortRunHighGrayLevelEmphasis" 24070.000000 ########
#     8.         "HighGrayLevelRunEmphasis" 23497.000000 #######
#     9.      "LongRunLowGrayLevelEmphasis" 23056.000000 #######
#    10.          "LowGrayLevelRunEmphasis" 22031.000000 ######
#    11.                      "RunVariance" 21538.000000 #####
#    12.                 "ShortRunEmphasis" 20255.000000 ###
#    13. "RunLengthNonUniformityNormalized" 20021.000000 ###
#    14.                  "LongRunEmphasis" 19052.000000 ##
#    15.           "RunLengthNonUniformity" 18257.000000 #
#    16.                    "RunPercentage" 17330.000000
#
# Variable Importance: SUM_SCORE:
#     1.     "LongRunHighGrayLevelEmphasis" 1134064.061225 ################
#     2.    "ShortRunHighGrayLevelEmphasis" 631849.046693 #######
#     3.         "HighGrayLevelRunEmphasis" 620791.076587 #######
#     4.     "ShortRunLowGrayLevelEmphasis" 435053.929387 ####
#     5.           "GrayLevelNonUniformity" 399953.061669 ####
#     6.          "LowGrayLevelRunEmphasis" 385496.240411 ###
#     7.                       "RunEntropy" 324295.746851 ##
#     8.      "LongRunLowGrayLevelEmphasis" 323272.853095 ##
#     9. "GrayLevelNonUniformityNormalized" 244474.146644 #
#    10.                 "ShortRunEmphasis" 205517.593139 #
#    11. "RunLengthNonUniformityNormalized" 198054.549996
#    12.                "GrayLevelVariance" 191784.832829
#    13.                      "RunVariance" 189495.969876
#    14.                  "LongRunEmphasis" 150643.962788
#    15.           "RunLengthNonUniformity" 141351.656137
#    16.                    "RunPercentage" 138372.325842
#
#
#
# Winner takes all: true
# Out-of-bag evaluation: accuracy:0.963087 logloss:0.20518
# Number of trees: 300
# Total number of nodes: 748112
#
# Number of nodes by tree:
# Count: 300 Average: 2493.71 StdDev: 152.453
# Min: 2017 Max: 2931 Ignored: 0
# ----------------------------------------------
# [ 2017, 2062)  2   0.67%   0.67%
# [ 2062, 2108)  2   0.67%   1.33%
# [ 2108, 2154)  3   1.00%   2.33% #
# [ 2154, 2200)  6   2.00%   4.33% #
# [ 2200, 2245)  4   1.33%   5.67% #
# [ 2245, 2291) 13   4.33%  10.00% ###
# [ 2291, 2337)  7   2.33%  12.33% ##
# [ 2337, 2383) 28   9.33%  21.67% ######
# [ 2383, 2428) 27   9.00%  30.67% ######
# [ 2428, 2474) 44  14.67%  45.33% ##########
# [ 2474, 2520) 31  10.33%  55.67% #######
# [ 2520, 2566) 30  10.00%  65.67% #######
# [ 2566, 2611) 26   8.67%  74.33% ######
# [ 2611, 2657) 35  11.67%  86.00% ########
# [ 2657, 2703) 20   6.67%  92.67% #####
# [ 2703, 2749) 15   5.00%  97.67% ###
# [ 2749, 2794)  2   0.67%  98.33%
# [ 2794, 2840)  4   1.33%  99.67% #
# [ 2840, 2886)  0   0.00%  99.67%
# [ 2886, 2931]  1   0.33% 100.00%
#
# Depth by leafs:
# Count: 374206 Average: 12.5779 StdDev: 2.23921
# Min: 2 Max: 15 Ignored: 0
# ----------------------------------------------
# [  2,  3)     2   0.00%   0.00%
# [  3,  4)    30   0.01%   0.01%
# [  4,  5)   328   0.09%   0.10%
# [  5,  6)  1103   0.29%   0.39%
# [  6,  7)  2620   0.70%   1.09%
# [  7,  8)  5866   1.57%   2.66% #
# [  8,  9) 11041   2.95%   5.61% #
# [  9, 10) 19124   5.11%  10.72% ##
# [ 10, 11) 28867   7.71%  18.43% ###
# [ 11, 12) 39837  10.65%  29.08% ####
# [ 12, 13) 50143  13.40%  42.48% #####
# [ 13, 14) 57390  15.34%  57.82% ######
# [ 14, 15) 59905  16.01%  73.82% ######
# [ 15, 15] 97950  26.18% 100.00% ##########
#
# Number of training obs by leaf:
# Count: 374206 Average: 71.4978 StdDev: 282.481
# Min: 5 Max: 8262 Ignored: 0
# ----------------------------------------------
# [    5,  417) 360921  96.45%  96.45% ##########
# [  417,  830)   7284   1.95%  98.40%
# [  830, 1243)   2377   0.64%  99.03%
# [ 1243, 1656)   1197   0.32%  99.35%
# [ 1656, 2069)    712   0.19%  99.54%
# [ 2069, 2482)    559   0.15%  99.69%
# [ 2482, 2895)    321   0.09%  99.78%
# [ 2895, 3308)    233   0.06%  99.84%
# [ 3308, 3721)    171   0.05%  99.88%
# [ 3721, 4134)    119   0.03%  99.92%
# [ 4134, 4546)     82   0.02%  99.94%
# [ 4546, 4959)     64   0.02%  99.96%
# [ 4959, 5372)     47   0.01%  99.97%
# [ 5372, 5785)     43   0.01%  99.98%
# [ 5785, 6198)     27   0.01%  99.99%
# [ 6198, 6611)     23   0.01%  99.99%
# [ 6611, 7024)     11   0.00% 100.00%
# [ 7024, 7437)      6   0.00% 100.00%
# [ 7437, 7850)      6   0.00% 100.00%
# [ 7850, 8262]      3   0.00% 100.00%
#
# Attribute in nodes:
# 	29775 : GrayLevelNonUniformity [NUMERICAL]
# 	29305 : LongRunHighGrayLevelEmphasis [NUMERICAL]
# 	28717 : RunEntropy [NUMERICAL]
# 	27250 : GrayLevelVariance [NUMERICAL]
# 	25426 : GrayLevelNonUniformityNormalized [NUMERICAL]
# 	24326 : ShortRunLowGrayLevelEmphasis [NUMERICAL]
# 	24070 : ShortRunHighGrayLevelEmphasis [NUMERICAL]
# 	23497 : HighGrayLevelRunEmphasis [NUMERICAL]
# 	23056 : LongRunLowGrayLevelEmphasis [NUMERICAL]
# 	22031 : LowGrayLevelRunEmphasis [NUMERICAL]
# 	21538 : RunVariance [NUMERICAL]
# 	20255 : ShortRunEmphasis [NUMERICAL]
# 	20021 : RunLengthNonUniformityNormalized [NUMERICAL]
# 	19052 : LongRunEmphasis [NUMERICAL]
# 	18257 : RunLengthNonUniformity [NUMERICAL]
# 	17330 : RunPercentage [NUMERICAL]
#
# Attribute in nodes with depth <= 0:
# 	96 : LongRunHighGrayLevelEmphasis [NUMERICAL]
# 	58 : ShortRunHighGrayLevelEmphasis [NUMERICAL]
# 	49 : HighGrayLevelRunEmphasis [NUMERICAL]
# 	35 : ShortRunLowGrayLevelEmphasis [NUMERICAL]
# 	26 : LowGrayLevelRunEmphasis [NUMERICAL]
# 	17 : LongRunLowGrayLevelEmphasis [NUMERICAL]
# 	9 : GrayLevelNonUniformityNormalized [NUMERICAL]
# 	6 : GrayLevelNonUniformity [NUMERICAL]
# 	2 : RunVariance [NUMERICAL]
# 	2 : LongRunEmphasis [NUMERICAL]
#
# Attribute in nodes with depth <= 1:
# 	274 : LongRunHighGrayLevelEmphasis [NUMERICAL]
# 	159 : HighGrayLevelRunEmphasis [NUMERICAL]
# 	120 : ShortRunHighGrayLevelEmphasis [NUMERICAL]
# 	89 : ShortRunLowGrayLevelEmphasis [NUMERICAL]
# 	81 : LowGrayLevelRunEmphasis [NUMERICAL]
# 	76 : LongRunLowGrayLevelEmphasis [NUMERICAL]
# 	32 : RunLengthNonUniformityNormalized [NUMERICAL]
# 	19 : ShortRunEmphasis [NUMERICAL]
# 	17 : GrayLevelNonUniformityNormalized [NUMERICAL]
# 	16 : GrayLevelNonUniformity [NUMERICAL]
# 	7 : RunVariance [NUMERICAL]
# 	4 : LongRunEmphasis [NUMERICAL]
# 	3 : RunEntropy [NUMERICAL]
# 	2 : GrayLevelVariance [NUMERICAL]
# 	1 : RunLengthNonUniformity [NUMERICAL]
#
# Attribute in nodes with depth <= 2:
# 	523 : LongRunHighGrayLevelEmphasis [NUMERICAL]
# 	292 : HighGrayLevelRunEmphasis [NUMERICAL]
# 	256 : ShortRunHighGrayLevelEmphasis [NUMERICAL]
# 	168 : ShortRunLowGrayLevelEmphasis [NUMERICAL]
# 	166 : LowGrayLevelRunEmphasis [NUMERICAL]
# 	139 : LongRunLowGrayLevelEmphasis [NUMERICAL]
# 	98 : RunLengthNonUniformityNormalized [NUMERICAL]
# 	83 : ShortRunEmphasis [NUMERICAL]
# 	78 : GrayLevelNonUniformity [NUMERICAL]
# 	66 : GrayLevelNonUniformityNormalized [NUMERICAL]
# 	61 : RunEntropy [NUMERICAL]
# 	45 : GrayLevelVariance [NUMERICAL]
# 	39 : RunVariance [NUMERICAL]
# 	35 : RunLengthNonUniformity [NUMERICAL]
# 	25 : RunPercentage [NUMERICAL]
# 	24 : LongRunEmphasis [NUMERICAL]
#
# Attribute in nodes with depth <= 3:
# 	889 : LongRunHighGrayLevelEmphasis [NUMERICAL]
# 	499 : HighGrayLevelRunEmphasis [NUMERICAL]
# 	427 : ShortRunHighGrayLevelEmphasis [NUMERICAL]
# 	332 : LowGrayLevelRunEmphasis [NUMERICAL]
# 	323 : ShortRunLowGrayLevelEmphasis [NUMERICAL]
# 	265 : LongRunLowGrayLevelEmphasis [NUMERICAL]
# 	260 : GrayLevelNonUniformity [NUMERICAL]
# 	237 : RunEntropy [NUMERICAL]
# 	221 : RunLengthNonUniformityNormalized [NUMERICAL]
# 	204 : GrayLevelNonUniformityNormalized [NUMERICAL]
# 	169 : ShortRunEmphasis [NUMERICAL]
# 	163 : GrayLevelVariance [NUMERICAL]
# 	145 : RunVariance [NUMERICAL]
# 	124 : RunLengthNonUniformity [NUMERICAL]
# 	103 : RunPercentage [NUMERICAL]
# 	103 : LongRunEmphasis [NUMERICAL]
#
# Attribute in nodes with depth <= 5:
# 	2226 : LongRunHighGrayLevelEmphasis [NUMERICAL]
# 	1330 : RunEntropy [NUMERICAL]
# 	1319 : GrayLevelNonUniformity [NUMERICAL]
# 	1260 : HighGrayLevelRunEmphasis [NUMERICAL]
# 	1177 : ShortRunHighGrayLevelEmphasis [NUMERICAL]
# 	1072 : ShortRunLowGrayLevelEmphasis [NUMERICAL]
# 	995 : LowGrayLevelRunEmphasis [NUMERICAL]
# 	968 : GrayLevelVariance [NUMERICAL]
# 	947 : GrayLevelNonUniformityNormalized [NUMERICAL]
# 	925 : LongRunLowGrayLevelEmphasis [NUMERICAL]
# 	916 : RunLengthNonUniformityNormalized [NUMERICAL]
# 	821 : ShortRunEmphasis [NUMERICAL]
# 	760 : RunVariance [NUMERICAL]
# 	630 : RunLengthNonUniformity [NUMERICAL]
# 	627 : RunPercentage [NUMERICAL]
# 	600 : LongRunEmphasis [NUMERICAL]
#
# Condition type in nodes:
# 	373906 : HigherCondition
# Condition type in nodes with depth <= 0:
# 	300 : HigherCondition
# Condition type in nodes with depth <= 1:
# 	900 : HigherCondition
# Condition type in nodes with depth <= 2:
# 	2098 : HigherCondition
# Condition type in nodes with depth <= 3:
# 	4464 : HigherCondition
# Condition type in nodes with depth <= 5:
# 	16573 : HigherCondition
# Node format: NOT_SET
#
# Training OOB:
# 	trees: 1, Out-of-bag evaluation: accuracy:0.94846 logloss:1.85769
# 	trees: 11, Out-of-bag evaluation: accuracy:0.959223 logloss:0.803162
# 	trees: 21, Out-of-bag evaluation: accuracy:0.961042 logloss:0.561722
# 	trees: 31, Out-of-bag evaluation: accuracy:0.961316 logloss:0.467155
# 	trees: 41, Out-of-bag evaluation: accuracy:0.961943 logloss:0.409317
# 	trees: 51, Out-of-bag evaluation: accuracy:0.962022 logloss:0.377892
# 	trees: 61, Out-of-bag evaluation: accuracy:0.962313 logloss:0.348143
# 	trees: 71, Out-of-bag evaluation: accuracy:0.96237 logloss:0.327346
# 	trees: 81, Out-of-bag evaluation: accuracy:0.962482 logloss:0.312425
# 	trees: 91, Out-of-bag evaluation: accuracy:0.962683 logloss:0.301708
# 	trees: 101, Out-of-bag evaluation: accuracy:0.96274 logloss:0.292972
# 	trees: 111, Out-of-bag evaluation: accuracy:0.962908 logloss:0.281809
# 	trees: 121, Out-of-bag evaluation: accuracy:0.962863 logloss:0.272362
# 	trees: 131, Out-of-bag evaluation: accuracy:0.962964 logloss:0.264468
# 	trees: 141, Out-of-bag evaluation: accuracy:0.962941 logloss:0.257525
# 	trees: 151, Out-of-bag evaluation: accuracy:0.962953 logloss:0.248104
# 	trees: 161, Out-of-bag evaluation: accuracy:0.962818 logloss:0.244506
# 	trees: 171, Out-of-bag evaluation: accuracy:0.963042 logloss:0.239085
# 	trees: 181, Out-of-bag evaluation: accuracy:0.963132 logloss:0.234511
# 	trees: 191, Out-of-bag evaluation: accuracy:0.96311 logloss:0.231709
# 	trees: 201, Out-of-bag evaluation: accuracy:0.963087 logloss:0.227779
# 	trees: 211, Out-of-bag evaluation: accuracy:0.963121 logloss:0.225642
# 	trees: 221, Out-of-bag evaluation: accuracy:0.962986 logloss:0.221421
# 	trees: 231, Out-of-bag evaluation: accuracy:0.963031 logloss:0.217116
# 	trees: 241, Out-of-bag evaluation: accuracy:0.963042 logloss:0.215981
# 	trees: 251, Out-of-bag evaluation: accuracy:0.963054 logloss:0.212506
# 	trees: 261, Out-of-bag evaluation: accuracy:0.963087 logloss:0.211078
# 	trees: 271, Out-of-bag evaluation: accuracy:0.963199 logloss:0.209977
# 	trees: 281, Out-of-bag evaluation: accuracy:0.963177 logloss:0.20859
# 	trees: 291, Out-of-bag evaluation: accuracy:0.963121 logloss:0.206882
# 	trees: 300, Out-of-bag evaluation: accuracy:0.963087 logloss:0.20518

# %%
# Model features
model.make_inspector().features()
# Out:
# ["GrayLevelNonUniformity" (1; #0),
#  "GrayLevelNonUniformityNormalized" (1; #1),
#  "GrayLevelVariance" (1; #2),
#  "HighGrayLevelRunEmphasis" (1; #3),
#  "LongRunEmphasis" (1; #4),
#  "LongRunHighGrayLevelEmphasis" (1; #5),
#  "LongRunLowGrayLevelEmphasis" (1; #6),
#  "LowGrayLevelRunEmphasis" (1; #7),
#  "RunEntropy" (1; #8),
#  "RunLengthNonUniformity" (1; #9),
#  "RunLengthNonUniformityNormalized" (1; #10),
#  "RunPercentage" (1; #11),
#  "RunVariance" (1; #12),
#  "ShortRunEmphasis" (1; #13),
#  "ShortRunHighGrayLevelEmphasis" (1; #14),
#  "ShortRunLowGrayLevelEmphasis" (1; #15)]

# %%
# Feature importance
model.make_inspector().variable_importances()
# Out:
# {'INV_MEAN_MIN_DEPTH': [("LongRunHighGrayLevelEmphasis" (1; #5),
#    0.22449664642224101),
#   ("HighGrayLevelRunEmphasis" (1; #3), 0.1411987168208044),
#   ("ShortRunHighGrayLevelEmphasis" (1; #14), 0.13745855848838137),
#   ("LowGrayLevelRunEmphasis" (1; #7), 0.11626560913546181),
#   ("GrayLevelNonUniformity" (1; #0), 0.11573959722579334),
#   ("ShortRunLowGrayLevelEmphasis" (1; #15), 0.11539367677809133),
#   ("LongRunLowGrayLevelEmphasis" (1; #6), 0.11226589542330306),
#   ("RunEntropy" (1; #8), 0.10821846033682879),
#   ("RunLengthNonUniformityNormalized" (1; #10), 0.1055485469219038),
#   ("ShortRunEmphasis" (1; #13), 0.10226190533436136),
#   ("GrayLevelNonUniformityNormalized" (1; #1), 0.09939205349234662),
#   ("RunVariance" (1; #12), 0.09160492816027611),
#   ("GrayLevelVariance" (1; #2), 0.08895406306479282),
#   ("RunLengthNonUniformity" (1; #9), 0.08707835450636636),
#   ("LongRunEmphasis" (1; #4), 0.0867696735539277),
#   ("RunPercentage" (1; #11), 0.08567838217221427)],
#  'NUM_AS_ROOT': [("LongRunHighGrayLevelEmphasis" (1; #5), 96.0),
#   ("ShortRunHighGrayLevelEmphasis" (1; #14), 58.0),
#   ("HighGrayLevelRunEmphasis" (1; #3), 49.0),
#   ("ShortRunLowGrayLevelEmphasis" (1; #15), 35.0),
#   ("LowGrayLevelRunEmphasis" (1; #7), 26.0),
#   ("LongRunLowGrayLevelEmphasis" (1; #6), 17.0),
#   ("GrayLevelNonUniformityNormalized" (1; #1), 9.0),
#   ("GrayLevelNonUniformity" (1; #0), 6.0),
#   ("LongRunEmphasis" (1; #4), 2.0),
#   ("RunVariance" (1; #12), 2.0)],
#  'SUM_SCORE': [("LongRunHighGrayLevelEmphasis" (1; #5), 1134064.061225198),
#   ("ShortRunHighGrayLevelEmphasis" (1; #14), 631849.046692559),
#   ("HighGrayLevelRunEmphasis" (1; #3), 620791.0765866614),
#   ("ShortRunLowGrayLevelEmphasis" (1; #15), 435053.92938683816),
#   ("GrayLevelNonUniformity" (1; #0), 399953.06166913174),
#   ("LowGrayLevelRunEmphasis" (1; #7), 385496.2404113539),
#   ("RunEntropy" (1; #8), 324295.7468506497),
#   ("LongRunLowGrayLevelEmphasis" (1; #6), 323272.8530945537),
#   ("GrayLevelNonUniformityNormalized" (1; #1), 244474.14664412846),
#   ("ShortRunEmphasis" (1; #13), 205517.59313897107),
#   ("RunLengthNonUniformityNormalized" (1; #10), 198054.54999639507),
#   ("GrayLevelVariance" (1; #2), 191784.8328287533),
#   ("RunVariance" (1; #12), 189495.96987569032),
#   ("LongRunEmphasis" (1; #4), 150643.96278834893),
#   ("RunLengthNonUniformity" (1; #9), 141351.65613683933),
#   ("RunPercentage" (1; #11), 138372.32584225482)],
#  'NUM_NODES': [("GrayLevelNonUniformity" (1; #0), 29775.0),
#   ("LongRunHighGrayLevelEmphasis" (1; #5), 29305.0),
#   ("RunEntropy" (1; #8), 28717.0),
#   ("GrayLevelVariance" (1; #2), 27250.0),
#   ("GrayLevelNonUniformityNormalized" (1; #1), 25426.0),
#   ("ShortRunLowGrayLevelEmphasis" (1; #15), 24326.0),
#   ("ShortRunHighGrayLevelEmphasis" (1; #14), 24070.0),
#   ("HighGrayLevelRunEmphasis" (1; #3), 23497.0),
#   ("LongRunLowGrayLevelEmphasis" (1; #6), 23056.0),
#   ("LowGrayLevelRunEmphasis" (1; #7), 22031.0),
#   ("RunVariance" (1; #12), 21538.0),
#   ("ShortRunEmphasis" (1; #13), 20255.0),
#   ("RunLengthNonUniformityNormalized" (1; #10), 20021.0),
#   ("LongRunEmphasis" (1; #4), 19052.0),
#   ("RunLengthNonUniformity" (1; #9), 18257.0),
#   ("RunPercentage" (1; #11), 17330.0)]}

# %%
# Model self evaluation
model.make_inspector().evaluation()
# Out:
# Evaluation(num_examples=89183, accuracy=0.9630871354406109, loss=0.20518012395148114, rmse=None, ndcg=None, aucs=None, auuc=None, qini=None)

# %%
logs = model.make_inspector().training_logs()

plt.figure(figsize=(12, 4))
plt.subplot(1, 2, 1)
plt.plot([log.num_trees for log in logs], [log.evaluation.accuracy for log in logs])
plt.xlabel("Number of trees")
plt.ylabel("Accuracy (out-of-bag)")
plt.subplot(1, 2, 2)
plt.plot([log.num_trees for log in logs], [log.evaluation.loss for log in logs])
plt.xlabel("Number of trees")
plt.ylabel("Logloss (out-of-bag)")
plt.show()

# %% [markdown]
# Calculate the score of our hold-out validation dataset

# %%
predictions = model.predict(val_ds)
y_true      = validation_data["label"]

from sklearn.metrics import roc_auc_score
ROC_AUC = roc_auc_score(y_true, predictions)
print("The ROC AUC score is %.5f" % ROC_AUC )
# Out:
# 23/23 [==============================] - 1s 27ms/step
# The ROC AUC score is 0.95767

# %%
# Compute binary classification metrics with sklearn
import numpy as np
from sklearn.metrics import (
    accuracy_score,
    precision_score,
    recall_score,
    f1_score,
    roc_auc_score,
    average_precision_score,
    confusion_matrix,
    classification_report,
    matthews_corrcoef,
    log_loss,
    brier_score_loss,
)

# Get predictions (probabilities or class labels)
preds = model.predict(val_ds)
# If model outputs probabilities, convert to labels by threshold 0.5
if preds.ndim == 2:
    # For TFDF classification, preds may be class probabilities with shape (N, 2)
    if preds.shape[1] == 2:
        pos_probs = preds[:, 1]
    else:
        # If single-probability column (positive class)
        pos_probs = preds[:, -1]
    y_pred = (pos_probs >= 0.5).astype(int)
else:
    # Already class labels
    y_pred = preds.astype(int)
    pos_probs = None

# Ground truth labels (must be 0/1 integers)
y_true = validation_data["label"].astype(int).to_numpy()

# Core metrics
metrics = {}
metrics["accuracy"] = accuracy_score(y_true, y_pred)
metrics["precision"] = precision_score(y_true, y_pred, zero_division=0)
metrics["recall"] = recall_score(y_true, y_pred, zero_division=0)
metrics["f1"] = f1_score(y_true, y_pred, zero_division=0)
metrics["mcc"] = matthews_corrcoef(y_true, y_pred)

# Probabilistic metrics (only if we have probabilities)
if pos_probs is not None:
    metrics["roc_auc"] = roc_auc_score(y_true, pos_probs)
    metrics["pr_auc"] = average_precision_score(y_true, pos_probs)
    metrics["log_loss"] = log_loss(y_true, pos_probs, labels=[0,1])
    metrics["brier_score"] = brier_score_loss(y_true, pos_probs)

# Confusion matrix and detailed report
cm = confusion_matrix(y_true, y_pred, labels=[0,1])
report = classification_report(y_true, y_pred, digits=4)

print("Sklearn binary metrics:")
for k, v in metrics.items():
    print(f"{k}: {v:.4f}")
print("\nConfusion matrix:\n", cm)
print("\nClassification report:\n", report)
# Out:
# 23/23 [==============================] - 1s 27ms/step
# Sklearn binary metrics:
# accuracy: 0.9643
# precision: 0.8623
# recall: 0.5909
# f1: 0.7012
# mcc: 0.6968
# roc_auc: 0.9577
# pr_auc: 0.7988
# log_loss: 0.1150
# brier_score: 0.0279
#
# Confusion matrix:
#  [[20568   149]
#  [  646   933]]
#
# Classification report:
#                precision    recall  f1-score   support
#
#            0     0.9695    0.9928    0.9810     20717
#            1     0.8623    0.5909    0.7012      1579
#
#     accuracy                         0.9643     22296
#    macro avg     0.9159    0.7918    0.8411     22296
# weighted avg     0.9620    0.9643    0.9612     22296
