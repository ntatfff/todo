# %%
# Import packages and modules
import numpy  as np
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow_decision_forests as tfdf

from sklearn.model_selection import train_test_split
# Out:
# 2026-05-29 17:21:51.795737: I tensorflow/core/util/port.cc:113] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2026-05-29 17:21:51.839254: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2026-05-29 17:21:52.493690: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
# Check the version of TensorFlow Decision Forests
print("Found TensorFlow Decision Forests v" + tfdf.__version__)
# Out:
# Found TensorFlow Decision Forests v1.9.1

# %%
# train/validation/test = 70/10/20
dataset = pd.read_csv('dataset/glrlm/kernel5-radius5/dataset.200p.csv')

train_data, temp_data = train_test_split(
    dataset, test_size=0.3, random_state=42
 )
validation_data, test_data = train_test_split(
    temp_data, test_size=2/3, random_state=42
 )

# %%
from sklearn.utils.class_weight import compute_class_weight

# tinh class weight tren tap train
classes = np.array([0, 1])
weights = compute_class_weight(class_weight="balanced", classes=classes, y=train_data["label"])
class_weight = {0: weights[0], 1: weights[1]}

# gan sample_weight cho tung dong
train_data["sample_weight"] = train_data["label"].map(class_weight)
validation_data["sample_weight"] = validation_data["label"].map(class_weight)
test_data["sample_weight"] = test_data["label"].map(class_weight)

# Convert the dataset into a TensorFlow dataset.
train_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    train_data, label="label", weight="sample_weight"
)         
val_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    validation_data, label="label", weight="sample_weight"
)
test_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    test_data, label="label", weight="sample_weight"
)
# Out:
# 2026-05-29 17:21:55.150417: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:984] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2026-05-29 17:21:55.150952: W tensorflow/core/common_runtime/gpu/gpu_device.cc:2251] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...

# %%
import keras

# %%
# %%time

# Train a Random Forest model.
model = tfdf.keras.RandomForestModel()

# Add evaluation metrics
model.compile(
    metrics=["accuracy"]
)
model.fit(x=train_ds)

# # Train a Gradient Boosted Trees model.
# model = tfdf.keras.GradientBoostedTreesModel(num_trees=1500)
# model.fit(train_ds)
# Out:
# Use /tmp/tmpjfxspu6k as temporary training directory
# Reading training dataset...
# Training dataset read in 0:00:02.992195. Found 156683 examples.
# Training model...
# [INFO 26-05-29 17:22:16.3752 UTC kernel.cc:1233] Loading model from path /tmp/tmpjfxspu6k/model/ with prefix 8c973bd1cf11422c
# Model trained in 0:00:19.497597
# Compiling model...
# [INFO 26-05-29 17:22:17.6246 UTC decision_forest.cc:734] Model loaded with 300 root(s), 1017662 node(s), and 16 input feature(s).
# [INFO 26-05-29 17:22:17.6247 UTC abstract_model.cc:1362] Engine "RandomForestOptPred" built
# [INFO 26-05-29 17:22:17.6247 UTC kernel.cc:1061] Use fast generic engine
# Model compiled.
# CPU times: user 3min 11s, sys: 1.72 s, total: 3min 13s
# Wall time: 25.4 s

# %%
# Evaluate the model
evaluate = model.evaluate(val_ds, return_dict=True)
print()

for name, value in evaluate.items():
    print(f"{name}: {value:.4f}")
# Out:
# WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 23/23 [==============================] - 3s 31ms/step - loss: 0.0000e+00 - accuracy: 0.9270
#
# loss: 0.0000
# accuracy: 0.9270

# %%
# Model Summary
model.summary()
# Out:
# Model: "random_forest_model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
# =================================================================
# Total params: 1 (1.00 Byte)
# Trainable params: 0 (0.00 Byte)
# Non-trainable params: 1 (1.00 Byte)
# _________________________________________________________________
# Type: "RANDOM_FOREST"
# Task: CLASSIFICATION
# Label: "__LABEL"
#
# Input Features (16):
# 	GrayLevelNonUniformity
# 	GrayLevelNonUniformityNormalized
# 	GrayLevelVariance
# 	HighGrayLevelRunEmphasis
# 	LongRunEmphasis
# 	LongRunHighGrayLevelEmphasis
# 	LongRunLowGrayLevelEmphasis
# 	LowGrayLevelRunEmphasis
# 	RunEntropy
# 	RunLengthNonUniformity
# 	RunLengthNonUniformityNormalized
# 	RunPercentage
# 	RunVariance
# 	ShortRunEmphasis
# 	ShortRunHighGrayLevelEmphasis
# 	ShortRunLowGrayLevelEmphasis
#
# Trained with weights
#
# Variable Importance: INV_MEAN_MIN_DEPTH:
#     1.     "LongRunHighGrayLevelEmphasis"  0.168411 ################
#     2.         "HighGrayLevelRunEmphasis"  0.156115 #############
#     3.          "LowGrayLevelRunEmphasis"  0.149846 ############
#     4.    "ShortRunHighGrayLevelEmphasis"  0.144827 ###########
#     5.     "ShortRunLowGrayLevelEmphasis"  0.129589 ########
#     6.                       "RunEntropy"  0.121991 #######
#     7.           "GrayLevelNonUniformity"  0.113319 #####
#     8.      "LongRunLowGrayLevelEmphasis"  0.102825 ###
#     9. "GrayLevelNonUniformityNormalized"  0.092892 #
#    10.                      "RunVariance"  0.092766 #
#    11.                "GrayLevelVariance"  0.090982 #
#    12.                 "ShortRunEmphasis"  0.087358
#    13. "RunLengthNonUniformityNormalized"  0.086025
#    14.                  "LongRunEmphasis"  0.085483
#    15.                    "RunPercentage"  0.084580
#    16.           "RunLengthNonUniformity"  0.083697
#
# Variable Importance: NUM_AS_ROOT:
#     1.          "LowGrayLevelRunEmphasis" 105.000000 ################
#     2.     "ShortRunLowGrayLevelEmphasis" 57.000000 ########
#     3.         "HighGrayLevelRunEmphasis" 39.000000 #####
#     4.     "LongRunHighGrayLevelEmphasis" 30.000000 ####
#     5.      "LongRunLowGrayLevelEmphasis" 28.000000 ####
#     6.    "ShortRunHighGrayLevelEmphasis" 20.000000 ##
#     7.                       "RunEntropy" 12.000000 #
#     8.           "GrayLevelNonUniformity"  4.000000
#     9. "GrayLevelNonUniformityNormalized"  3.000000
#    10.                      "RunVariance"  2.000000
#
# Variable Importance: NUM_NODES:
#     1.           "GrayLevelNonUniformity" 40246.000000 ################
#     2.                       "RunEntropy" 39817.000000 ###############
#     3.     "LongRunHighGrayLevelEmphasis" 39030.000000 ##############
#     4.                "GrayLevelVariance" 37801.000000 #############
#     5. "GrayLevelNonUniformityNormalized" 33827.000000 #########
#     6.     "ShortRunLowGrayLevelEmphasis" 33652.000000 #########
#     7.         "HighGrayLevelRunEmphasis" 31781.000000 #######
#     8.    "ShortRunHighGrayLevelEmphasis" 31713.000000 #######
#     9.      "LongRunLowGrayLevelEmphasis" 31676.000000 #######
#    10.          "LowGrayLevelRunEmphasis" 30840.000000 ######
#    11.                      "RunVariance" 30771.000000 ######
#    12.                  "LongRunEmphasis" 26427.000000 ##
#    13.                 "ShortRunEmphasis" 26390.000000 ##
#    14. "RunLengthNonUniformityNormalized" 26149.000000 ##
#    15.           "RunLengthNonUniformity" 24726.000000
#    16.                    "RunPercentage" 23835.000000
#
# Variable Importance: SUM_SCORE:
#     1.     "LongRunHighGrayLevelEmphasis" 3399685.906790 ################
#     2.         "HighGrayLevelRunEmphasis" 2989435.800422 #############
#     3.          "LowGrayLevelRunEmphasis" 2962062.415487 #############
#     4.    "ShortRunHighGrayLevelEmphasis" 2598695.771283 ###########
#     5.     "ShortRunLowGrayLevelEmphasis" 2372976.666523 ##########
#     6.                       "RunEntropy" 2008690.650439 #######
#     7.           "GrayLevelNonUniformity" 1884805.884557 #######
#     8.      "LongRunLowGrayLevelEmphasis" 1453648.919688 ####
#     9. "GrayLevelNonUniformityNormalized" 1031276.280922 ##
#    10.                "GrayLevelVariance" 1029558.824843 ##
#    11.                      "RunVariance" 1008352.137303 ##
#    12.                 "ShortRunEmphasis" 782799.187085
#    13.                  "LongRunEmphasis" 748089.969534
#    14. "RunLengthNonUniformityNormalized" 728087.343244
#    15.                    "RunPercentage" 646475.868377
#    16.           "RunLengthNonUniformity" 630947.789954
#
#
#
# Winner takes all: true
# Out-of-bag evaluation: accuracy:0.857578 logloss:0.454046
# Number of trees: 300
# Total number of nodes: 1017662
#
# Number of nodes by tree:
# Count: 300 Average: 3392.21 StdDev: 207.924
# Min: 2771 Max: 3897 Ignored: 0
# ----------------------------------------------
# [ 2771, 2827)  1   0.33%   0.33%
# [ 2827, 2883)  1   0.33%   0.67%
# [ 2883, 2940)  6   2.00%   2.67% ##
# [ 2940, 2996)  5   1.67%   4.33% #
# [ 2996, 3052)  8   2.67%   7.00% ##
# [ 3052, 3109)  6   2.00%   9.00% ##
# [ 3109, 3165) 18   6.00%  15.00% #####
# [ 3165, 3221) 14   4.67%  19.67% ####
# [ 3221, 3278) 28   9.33%  29.00% #######
# [ 3278, 3334) 19   6.33%  35.33% #####
# [ 3334, 3390) 29   9.67%  45.00% #######
# [ 3390, 3447) 31  10.33%  55.33% ########
# [ 3447, 3503) 39  13.00%  68.33% ##########
# [ 3503, 3559) 26   8.67%  77.00% #######
# [ 3559, 3616) 32  10.67%  87.67% ########
# [ 3616, 3672) 14   4.67%  92.33% ####
# [ 3672, 3728) 11   3.67%  96.00% ###
# [ 3728, 3785)  8   2.67%  98.67% ##
# [ 3785, 3841)  2   0.67%  99.33% #
# [ 3841, 3897]  2   0.67% 100.00% #
#
# Depth by leafs:
# Count: 508981 Average: 12.9224 StdDev: 2.14432
# Min: 3 Max: 15 Ignored: 0
# ----------------------------------------------
# [  3,  4)      9   0.00%   0.00%
# [  4,  5)    141   0.03%   0.03%
# [  5,  6)    851   0.17%   0.20%
# [  6,  7)   2522   0.50%   0.69%
# [  7,  8)   6021   1.18%   1.88%
# [  8,  9)  11952   2.35%   4.22% #
# [  9, 10)  21177   4.16%   8.38% #
# [ 10, 11)  32784   6.44%  14.83% ##
# [ 11, 12)  46420   9.12%  23.95% ###
# [ 12, 13)  61576  12.10%  36.04% ####
# [ 13, 14)  74194  14.58%  50.62% ####
# [ 14, 15)  82994  16.31%  66.93% #####
# [ 15, 15] 168340  33.07% 100.00% ##########
#
# Number of training obs by leaf:
# Count: 508981 Average: 92.351 StdDev: 406.758
# Min: 5 Max: 15808 Ignored: 0
# ----------------------------------------------
# [     5,   795) 498954  98.03%  98.03% ##########
# [   795,  1585)   5207   1.02%  99.05%
# [  1585,  2375)   1916   0.38%  99.43%
# [  2375,  3165)   1049   0.21%  99.64%
# [  3165,  3956)    650   0.13%  99.76%
# [  3956,  4746)    359   0.07%  99.83%
# [  4746,  5536)    227   0.04%  99.88%
# [  5536,  6326)    158   0.03%  99.91%
# [  6326,  7116)    117   0.02%  99.93%
# [  7116,  7907)     89   0.02%  99.95%
# [  7907,  8697)     86   0.02%  99.97%
# [  8697,  9487)     51   0.01%  99.98%
# [  9487, 10277)     48   0.01%  99.99%
# [ 10277, 11067)     28   0.01%  99.99%
# [ 11067, 11858)     22   0.00% 100.00%
# [ 11858, 12648)      9   0.00% 100.00%
# [ 12648, 13438)      6   0.00% 100.00%
# [ 13438, 14228)      4   0.00% 100.00%
# [ 14228, 15018)      0   0.00% 100.00%
# [ 15018, 15808]      1   0.00% 100.00%
#
# Attribute in nodes:
# 	40246 : GrayLevelNonUniformity [NUMERICAL]
# 	39817 : RunEntropy [NUMERICAL]
# 	39030 : LongRunHighGrayLevelEmphasis [NUMERICAL]
# 	37801 : GrayLevelVariance [NUMERICAL]
# 	33827 : GrayLevelNonUniformityNormalized [NUMERICAL]
# 	33652 : ShortRunLowGrayLevelEmphasis [NUMERICAL]
# 	31781 : HighGrayLevelRunEmphasis [NUMERICAL]
# 	31713 : ShortRunHighGrayLevelEmphasis [NUMERICAL]
# 	31676 : LongRunLowGrayLevelEmphasis [NUMERICAL]
# 	30840 : LowGrayLevelRunEmphasis [NUMERICAL]
# 	30771 : RunVariance [NUMERICAL]
# 	26427 : LongRunEmphasis [NUMERICAL]
# 	26390 : ShortRunEmphasis [NUMERICAL]
# 	26149 : RunLengthNonUniformityNormalized [NUMERICAL]
# 	24726 : RunLengthNonUniformity [NUMERICAL]
# 	23835 : RunPercentage [NUMERICAL]
#
# Attribute in nodes with depth <= 0:
# 	105 : LowGrayLevelRunEmphasis [NUMERICAL]
# 	57 : ShortRunLowGrayLevelEmphasis [NUMERICAL]
# 	39 : HighGrayLevelRunEmphasis [NUMERICAL]
# 	30 : LongRunHighGrayLevelEmphasis [NUMERICAL]
# 	28 : LongRunLowGrayLevelEmphasis [NUMERICAL]
# 	20 : ShortRunHighGrayLevelEmphasis [NUMERICAL]
# 	12 : RunEntropy [NUMERICAL]
# 	4 : GrayLevelNonUniformity [NUMERICAL]
# 	3 : GrayLevelNonUniformityNormalized [NUMERICAL]
# 	2 : RunVariance [NUMERICAL]
#
# Attribute in nodes with depth <= 1:
# 	192 : LongRunHighGrayLevelEmphasis [NUMERICAL]
# 	186 : HighGrayLevelRunEmphasis [NUMERICAL]
# 	141 : LowGrayLevelRunEmphasis [NUMERICAL]
# 	114 : ShortRunLowGrayLevelEmphasis [NUMERICAL]
# 	113 : ShortRunHighGrayLevelEmphasis [NUMERICAL]
# 	50 : RunEntropy [NUMERICAL]
# 	44 : LongRunLowGrayLevelEmphasis [NUMERICAL]
# 	26 : GrayLevelNonUniformity [NUMERICAL]
# 	13 : GrayLevelVariance [NUMERICAL]
# 	12 : GrayLevelNonUniformityNormalized [NUMERICAL]
# 	4 : RunVariance [NUMERICAL]
# 	2 : ShortRunEmphasis [NUMERICAL]
# 	1 : RunPercentage [NUMERICAL]
# 	1 : RunLengthNonUniformityNormalized [NUMERICAL]
# 	1 : LongRunEmphasis [NUMERICAL]
#
# Attribute in nodes with depth <= 2:
# 	432 : LongRunHighGrayLevelEmphasis [NUMERICAL]
# 	374 : HighGrayLevelRunEmphasis [NUMERICAL]
# 	298 : ShortRunHighGrayLevelEmphasis [NUMERICAL]
# 	208 : LowGrayLevelRunEmphasis [NUMERICAL]
# 	179 : ShortRunLowGrayLevelEmphasis [NUMERICAL]
# 	158 : RunEntropy [NUMERICAL]
# 	92 : GrayLevelNonUniformity [NUMERICAL]
# 	82 : LongRunLowGrayLevelEmphasis [NUMERICAL]
# 	53 : RunVariance [NUMERICAL]
# 	44 : ShortRunEmphasis [NUMERICAL]
# 	40 : GrayLevelVariance [NUMERICAL]
# 	37 : LongRunEmphasis [NUMERICAL]
# 	31 : GrayLevelNonUniformityNormalized [NUMERICAL]
# 	30 : RunLengthNonUniformityNormalized [NUMERICAL]
# 	25 : RunPercentage [NUMERICAL]
# 	17 : RunLengthNonUniformity [NUMERICAL]
#
# Attribute in nodes with depth <= 3:
# 	860 : LongRunHighGrayLevelEmphasis [NUMERICAL]
# 	627 : HighGrayLevelRunEmphasis [NUMERICAL]
# 	493 : ShortRunHighGrayLevelEmphasis [NUMERICAL]
# 	430 : RunEntropy [NUMERICAL]
# 	362 : LowGrayLevelRunEmphasis [NUMERICAL]
# 	347 : ShortRunLowGrayLevelEmphasis [NUMERICAL]
# 	307 : GrayLevelNonUniformity [NUMERICAL]
# 	217 : LongRunLowGrayLevelEmphasis [NUMERICAL]
# 	153 : GrayLevelVariance [NUMERICAL]
# 	149 : GrayLevelNonUniformityNormalized [NUMERICAL]
# 	121 : RunVariance [NUMERICAL]
# 	116 : ShortRunEmphasis [NUMERICAL]
# 	93 : RunLengthNonUniformityNormalized [NUMERICAL]
# 	84 : LongRunEmphasis [NUMERICAL]
# 	68 : RunPercentage [NUMERICAL]
# 	64 : RunLengthNonUniformity [NUMERICAL]
#
# Attribute in nodes with depth <= 5:
# 	2387 : LongRunHighGrayLevelEmphasis [NUMERICAL]
# 	1701 : RunEntropy [NUMERICAL]
# 	1583 : HighGrayLevelRunEmphasis [NUMERICAL]
# 	1426 : GrayLevelNonUniformity [NUMERICAL]
# 	1305 : ShortRunHighGrayLevelEmphasis [NUMERICAL]
# 	1209 : ShortRunLowGrayLevelEmphasis [NUMERICAL]
# 	1180 : LowGrayLevelRunEmphasis [NUMERICAL]
# 	905 : GrayLevelNonUniformityNormalized [NUMERICAL]
# 	893 : LongRunLowGrayLevelEmphasis [NUMERICAL]
# 	834 : GrayLevelVariance [NUMERICAL]
# 	811 : RunVariance [NUMERICAL]
# 	751 : ShortRunEmphasis [NUMERICAL]
# 	723 : RunLengthNonUniformityNormalized [NUMERICAL]
# 	638 : LongRunEmphasis [NUMERICAL]
# 	618 : RunPercentage [NUMERICAL]
# 	599 : RunLengthNonUniformity [NUMERICAL]
#
# Condition type in nodes:
# 	508681 : HigherCondition
# Condition type in nodes with depth <= 0:
# 	300 : HigherCondition
# Condition type in nodes with depth <= 1:
# 	900 : HigherCondition
# Condition type in nodes with depth <= 2:
# 	2100 : HigherCondition
# Condition type in nodes with depth <= 3:
# 	4491 : HigherCondition
# Condition type in nodes with depth <= 5:
# 	17563 : HigherCondition
# Node format: NOT_SET
#
# Training OOB:
# 	trees: 1, Out-of-bag evaluation: accuracy:0.820376 logloss:6.47429
# 	trees: 11, Out-of-bag evaluation: accuracy:0.830955 logloss:2.6264
# 	trees: 21, Out-of-bag evaluation: accuracy:0.846112 logloss:1.61487
# 	trees: 31, Out-of-bag evaluation: accuracy:0.848532 logloss:1.22284
# 	trees: 41, Out-of-bag evaluation: accuracy:0.850429 logloss:1.02359
# 	trees: 51, Out-of-bag evaluation: accuracy:0.852369 logloss:0.898104
# 	trees: 61, Out-of-bag evaluation: accuracy:0.853275 logloss:0.81628
# 	trees: 71, Out-of-bag evaluation: accuracy:0.854716 logloss:0.758468
# 	trees: 81, Out-of-bag evaluation: accuracy:0.855358 logloss:0.7164
# 	trees: 91, Out-of-bag evaluation: accuracy:0.855385 logloss:0.685276
# 	trees: 101, Out-of-bag evaluation: accuracy:0.855533 logloss:0.642179
# 	trees: 111, Out-of-bag evaluation: accuracy:0.856173 logloss:0.618704
# 	trees: 121, Out-of-bag evaluation: accuracy:0.855741 logloss:0.593598
# 	trees: 131, Out-of-bag evaluation: accuracy:0.855693 logloss:0.57203
# 	trees: 141, Out-of-bag evaluation: accuracy:0.855785 logloss:0.55686
# 	trees: 151, Out-of-bag evaluation: accuracy:0.856507 logloss:0.549159
# 	trees: 161, Out-of-bag evaluation: accuracy:0.856376 logloss:0.538789
# 	trees: 171, Out-of-bag evaluation: accuracy:0.85626 logloss:0.527453
# 	trees: 181, Out-of-bag evaluation: accuracy:0.855962 logloss:0.52035
# 	trees: 191, Out-of-bag evaluation: accuracy:0.856134 logloss:0.506665
# 	trees: 201, Out-of-bag evaluation: accuracy:0.856318 logloss:0.498473
# 	trees: 211, Out-of-bag evaluation: accuracy:0.856502 logloss:0.491477
# 	trees: 221, Out-of-bag evaluation: accuracy:0.856945 logloss:0.487693
# 	trees: 231, Out-of-bag evaluation: accuracy:0.856632 logloss:0.484279
# 	trees: 241, Out-of-bag evaluation: accuracy:0.857048 logloss:0.480269
# 	trees: 251, Out-of-bag evaluation: accuracy:0.857338 logloss:0.472125
# 	trees: 261, Out-of-bag evaluation: accuracy:0.856691 logloss:0.464989
# 	trees: 271, Out-of-bag evaluation: accuracy:0.8573 logloss:0.45978
# 	trees: 281, Out-of-bag evaluation: accuracy:0.857477 logloss:0.457711
# 	trees: 291, Out-of-bag evaluation: accuracy:0.857685 logloss:0.454376
# 	trees: 300, Out-of-bag evaluation: accuracy:0.857578 logloss:0.454046

# %%
# Model features
model.make_inspector().features()
# Out:
# ["GrayLevelNonUniformity" (1; #0),
#  "GrayLevelNonUniformityNormalized" (1; #1),
#  "GrayLevelVariance" (1; #2),
#  "HighGrayLevelRunEmphasis" (1; #3),
#  "LongRunEmphasis" (1; #4),
#  "LongRunHighGrayLevelEmphasis" (1; #5),
#  "LongRunLowGrayLevelEmphasis" (1; #6),
#  "LowGrayLevelRunEmphasis" (1; #7),
#  "RunEntropy" (1; #8),
#  "RunLengthNonUniformity" (1; #9),
#  "RunLengthNonUniformityNormalized" (1; #10),
#  "RunPercentage" (1; #11),
#  "RunVariance" (1; #12),
#  "ShortRunEmphasis" (1; #13),
#  "ShortRunHighGrayLevelEmphasis" (1; #14),
#  "ShortRunLowGrayLevelEmphasis" (1; #15)]

# %%
# Feature importance
model.make_inspector().variable_importances()
# Out:
# {'INV_MEAN_MIN_DEPTH': [("LongRunHighGrayLevelEmphasis" (1; #5),
#    0.16841109419190625),
#   ("HighGrayLevelRunEmphasis" (1; #3), 0.15611525670202467),
#   ("LowGrayLevelRunEmphasis" (1; #7), 0.14984618234326014),
#   ("ShortRunHighGrayLevelEmphasis" (1; #14), 0.14482710315177535),
#   ("ShortRunLowGrayLevelEmphasis" (1; #15), 0.1295887780019457),
#   ("RunEntropy" (1; #8), 0.12199144493258032),
#   ("GrayLevelNonUniformity" (1; #0), 0.1133188434412618),
#   ("LongRunLowGrayLevelEmphasis" (1; #6), 0.10282516226775407),
#   ("GrayLevelNonUniformityNormalized" (1; #1), 0.09289183234969951),
#   ("RunVariance" (1; #12), 0.09276588261306759),
#   ("GrayLevelVariance" (1; #2), 0.09098248942317165),
#   ("ShortRunEmphasis" (1; #13), 0.08735820078205628),
#   ("RunLengthNonUniformityNormalized" (1; #10), 0.08602485360163302),
#   ("LongRunEmphasis" (1; #4), 0.08548346026474367),
#   ("RunPercentage" (1; #11), 0.08458033589512687),
#   ("RunLengthNonUniformity" (1; #9), 0.08369658618199863)],
#  'SUM_SCORE': [("LongRunHighGrayLevelEmphasis" (1; #5), 3399685.9067896623),
#   ("HighGrayLevelRunEmphasis" (1; #3), 2989435.800421976),
#   ("LowGrayLevelRunEmphasis" (1; #7), 2962062.4154865677),
#   ("ShortRunHighGrayLevelEmphasis" (1; #14), 2598695.7712833984),
#   ("ShortRunLowGrayLevelEmphasis" (1; #15), 2372976.6665234733),
#   ("RunEntropy" (1; #8), 2008690.6504392421),
#   ("GrayLevelNonUniformity" (1; #0), 1884805.884557196),
#   ("LongRunLowGrayLevelEmphasis" (1; #6), 1453648.9196876492),
#   ("GrayLevelNonUniformityNormalized" (1; #1), 1031276.2809224492),
#   ("GrayLevelVariance" (1; #2), 1029558.8248425628),
#   ("RunVariance" (1; #12), 1008352.1373031064),
#   ("ShortRunEmphasis" (1; #13), 782799.1870845285),
#   ("LongRunEmphasis" (1; #4), 748089.9695335889),
#   ("RunLengthNonUniformityNormalized" (1; #10), 728087.3432441258),
#   ("RunPercentage" (1; #11), 646475.8683773543),
#   ("RunLengthNonUniformity" (1; #9), 630947.7899539364)],
#  'NUM_AS_ROOT': [("LowGrayLevelRunEmphasis" (1; #7), 105.0),
#   ("ShortRunLowGrayLevelEmphasis" (1; #15), 57.0),
#   ("HighGrayLevelRunEmphasis" (1; #3), 39.0),
#   ("LongRunHighGrayLevelEmphasis" (1; #5), 30.0),
#   ("LongRunLowGrayLevelEmphasis" (1; #6), 28.0),
#   ("ShortRunHighGrayLevelEmphasis" (1; #14), 20.0),
#   ("RunEntropy" (1; #8), 12.0),
#   ("GrayLevelNonUniformity" (1; #0), 4.0),
#   ("GrayLevelNonUniformityNormalized" (1; #1), 3.0),
#   ("RunVariance" (1; #12), 2.0)],
#  'NUM_NODES': [("GrayLevelNonUniformity" (1; #0), 40246.0),
#   ("RunEntropy" (1; #8), 39817.0),
#   ("LongRunHighGrayLevelEmphasis" (1; #5), 39030.0),
#   ("GrayLevelVariance" (1; #2), 37801.0),
#   ("GrayLevelNonUniformityNormalized" (1; #1), 33827.0),
#   ("ShortRunLowGrayLevelEmphasis" (1; #15), 33652.0),
#   ("HighGrayLevelRunEmphasis" (1; #3), 31781.0),
#   ("ShortRunHighGrayLevelEmphasis" (1; #14), 31713.0),
#   ("LongRunLowGrayLevelEmphasis" (1; #6), 31676.0),
#   ("LowGrayLevelRunEmphasis" (1; #7), 30840.0),
#   ("RunVariance" (1; #12), 30771.0),
#   ("LongRunEmphasis" (1; #4), 26427.0),
#   ("ShortRunEmphasis" (1; #13), 26390.0),
#   ("RunLengthNonUniformityNormalized" (1; #10), 26149.0),
#   ("RunLengthNonUniformity" (1; #9), 24726.0),
#   ("RunPercentage" (1; #11), 23835.0)]}

# %%
# Model self evaluation
model.make_inspector().evaluation()
# Out:
# Evaluation(num_examples=156683, accuracy=0.857577715174621, loss=0.4540462842569075, rmse=None, ndcg=None, aucs=None, auuc=None, qini=None)

# %%
logs = model.make_inspector().training_logs()

plt.figure(figsize=(12, 4))
plt.subplot(1, 2, 1)
plt.plot([log.num_trees for log in logs], [log.evaluation.accuracy for log in logs])
plt.xlabel("Number of trees")
plt.ylabel("Accuracy (out-of-bag)")
plt.subplot(1, 2, 2)
plt.plot([log.num_trees for log in logs], [log.evaluation.loss for log in logs])
plt.xlabel("Number of trees")
plt.ylabel("Logloss (out-of-bag)")
plt.show()

# %% [markdown]
# Calculate the score of our hold-out validation dataset

# %%
predictions = model.predict(val_ds)
y_true      = validation_data["label"]

from sklearn.metrics import roc_auc_score
ROC_AUC = roc_auc_score(y_true, predictions)
print("The ROC AUC score is %.5f" % ROC_AUC )
# Out:
# 23/23 [==============================] - 1s 32ms/step
# The ROC AUC score is 0.94558

# %%
# Compute binary classification metrics with sklearn
import numpy as np
from sklearn.metrics import (
    accuracy_score,
    precision_score,
    recall_score,
    f1_score,
    roc_auc_score,
    average_precision_score,
    confusion_matrix,
    classification_report,
    matthews_corrcoef,
    log_loss,
    brier_score_loss,
)

# Get predictions (probabilities or class labels)
preds = model.predict(test_ds)
# If model outputs probabilities, convert to labels by threshold 0.5
if preds.ndim == 2:
    # For TFDF classification, preds may be class probabilities with shape (N, 2)
    if preds.shape[1] == 2:
        pos_probs = preds[:, 1]
    else:
        # If single-probability column (positive class)
        pos_probs = preds[:, -1]
    y_pred = (pos_probs >= 0.5).astype(int)
else:
    # Already class labels
    y_pred = preds.astype(int)
    pos_probs = None

# Ground truth labels (must be 0/1 integers)
y_true = test_data["label"].astype(int).to_numpy()

# Core metrics
metrics = {}
metrics["accuracy"] = accuracy_score(y_true, y_pred)
metrics["precision"] = precision_score(y_true, y_pred, zero_division=0)
metrics["recall"] = recall_score(y_true, y_pred, zero_division=0)
metrics["f1"] = f1_score(y_true, y_pred, zero_division=0)
metrics["mcc"] = matthews_corrcoef(y_true, y_pred)

# Probabilistic metrics (only if we have probabilities)
if pos_probs is not None:
    metrics["roc_auc"] = roc_auc_score(y_true, pos_probs)
    metrics["pr_auc"] = average_precision_score(y_true, pos_probs)
    metrics["log_loss"] = log_loss(y_true, pos_probs, labels=[0,1])
    metrics["brier_score"] = brier_score_loss(y_true, pos_probs)

# Confusion matrix and detailed report
cm = confusion_matrix(y_true, y_pred, labels=[0,1])
report = classification_report(y_true, y_pred, digits=4)

print("Sklearn binary metrics:")
for k, v in metrics.items():
    print(f"{k}: {v:.4f}")
print("\nConfusion matrix:\n", cm)
print("\nClassification report:\n", report)
# Out:
# 45/45 [==============================] - 1s 31ms/step
# Sklearn binary metrics:
# accuracy: 0.9256
# precision: 0.4508
# recall: 0.7604
# f1: 0.5660
# mcc: 0.5499
# roc_auc: 0.9449
# pr_auc: 0.6832
# log_loss: 0.1835
# brier_score: 0.0542
#
# Confusion matrix:
#  [[39268  2645]
#  [  684  2171]]
#
# Classification report:
#                precision    recall  f1-score   support
#
#            0     0.9829    0.9369    0.9593     41913
#            1     0.4508    0.7604    0.5660      2855
#
#     accuracy                         0.9256     44768
#    macro avg     0.7168    0.8487    0.7627     44768
# weighted avg     0.9489    0.9256    0.9343     44768
