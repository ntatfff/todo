# %%
# Import packages and modules
import numpy  as np
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow_decision_forests as tfdf

from sklearn.model_selection import train_test_split
# Out:
# 2026-05-18 18:07:30.172483: I tensorflow/core/util/port.cc:113] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2026-05-18 18:07:30.247754: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2026-05-18 18:07:31.236400: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
# Check the version of TensorFlow Decision Forests
print("Found TensorFlow Decision Forests v" + tfdf.__version__)
# Out:
# Found TensorFlow Decision Forests v1.9.1

# %%
# train/validation/test = 70/10/20
dataset = pd.read_csv('dataset/glrlm/kernel5-radius5/dataset.csv')

train_data, temp_data = train_test_split(
    dataset, test_size=0.3, random_state=42
 )
validation_data, test_data = train_test_split(
    temp_data, test_size=2/3, random_state=42
 )

# %%
# Convert the dataset into a TensorFlow dataset.
train_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    train_data, label="label"
)         
val_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    validation_data, label="label"
)
test_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    test_data, label="label"
)
# Out:
# 2026-05-18 18:07:33.421085: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:984] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2026-05-18 18:07:33.421727: W tensorflow/core/common_runtime/gpu/gpu_device.cc:2251] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...

# %%
import keras

# %%
# %%time

# Train a Random Forest model.
model = tfdf.keras.RandomForestModel()

# Add evaluation metrics
model.compile(
    metrics=["accuracy"]
)
model.fit(x=train_ds)

# # Train a Gradient Boosted Trees model.
# model = tfdf.keras.GradientBoostedTreesModel(num_trees=1500)
# model.fit(train_ds)
# Out:
# Use /tmp/tmpomtw8djk as temporary training directory
# Reading training dataset...
# Training dataset read in 0:00:04.906050. Found 78035 examples.
# Training model...
# [INFO 26-05-18 18:08:16.5304 UTC kernel.cc:1233] Loading model from path /tmp/tmpomtw8djk/model/ with prefix 57c5ba527ea34104
# [INFO 26-05-18 18:08:20.2169 UTC decision_forest.cc:734] Model loaded with 300 root(s), 688882 node(s), and 16 input feature(s).
# [INFO 26-05-18 18:08:20.2169 UTC abstract_model.cc:1362] Engine "RandomForestOptPred" built
# [INFO 26-05-18 18:08:20.2169 UTC kernel.cc:1061] Use fast generic engine
# Model trained in 0:00:41.792829
# Compiling model...
# Model compiled.
# CPU times: user 1min 45s, sys: 3.01 s, total: 1min 48s
# Wall time: 51 s

# %%
# Evaluate the model
evaluate = model.evaluate(val_ds, return_dict=True)
print()

for name, value in evaluate.items():
    print(f"{name}: {value:.4f}")
# Out:
# 12/12 [==============================] - 4s 39ms/step - loss: 0.0000e+00 - accuracy: 0.9647
#
# loss: 0.0000
# accuracy: 0.9647

# %%
# Model Summary
model.summary()
# Out:
# Model: "random_forest_model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
# =================================================================
# Total params: 1 (1.00 Byte)
# Trainable params: 0 (0.00 Byte)
# Non-trainable params: 1 (1.00 Byte)
# _________________________________________________________________
# Type: "RANDOM_FOREST"
# Task: CLASSIFICATION
# Label: "__LABEL"
#
# Input Features (16):
# 	GrayLevelNonUniformity
# 	GrayLevelNonUniformityNormalized
# 	GrayLevelVariance
# 	HighGrayLevelRunEmphasis
# 	LongRunEmphasis
# 	LongRunHighGrayLevelEmphasis
# 	LongRunLowGrayLevelEmphasis
# 	LowGrayLevelRunEmphasis
# 	RunEntropy
# 	RunLengthNonUniformity
# 	RunLengthNonUniformityNormalized
# 	RunPercentage
# 	RunVariance
# 	ShortRunEmphasis
# 	ShortRunHighGrayLevelEmphasis
# 	ShortRunLowGrayLevelEmphasis
#
# No weights
#
# Variable Importance: INV_MEAN_MIN_DEPTH:
#     1.     "LongRunHighGrayLevelEmphasis"  0.207436 ################
#     2.         "HighGrayLevelRunEmphasis"  0.153312 ########
#     3.    "ShortRunHighGrayLevelEmphasis"  0.138869 ######
#     4.     "ShortRunLowGrayLevelEmphasis"  0.119093 ####
#     5.          "LowGrayLevelRunEmphasis"  0.116869 ####
#     6.           "GrayLevelNonUniformity"  0.114440 ###
#     7.      "LongRunLowGrayLevelEmphasis"  0.113166 ###
#     8.                       "RunEntropy"  0.110061 ###
#     9.                 "ShortRunEmphasis"  0.105977 ##
#    10. "RunLengthNonUniformityNormalized"  0.105966 ##
#    11. "GrayLevelNonUniformityNormalized"  0.099253 #
#    12.                      "RunVariance"  0.093181
#    13.                "GrayLevelVariance"  0.089225
#    14.                  "LongRunEmphasis"  0.088089
#    15.           "RunLengthNonUniformity"  0.086935
#    16.                    "RunPercentage"  0.086577
#
# Variable Importance: NUM_AS_ROOT:
#     1.     "LongRunHighGrayLevelEmphasis" 83.000000 ################
#     2.         "HighGrayLevelRunEmphasis" 74.000000 ##############
#     3.    "ShortRunHighGrayLevelEmphasis" 54.000000 ##########
#     4.     "ShortRunLowGrayLevelEmphasis" 33.000000 ######
#     5.          "LowGrayLevelRunEmphasis" 21.000000 ###
#     6.      "LongRunLowGrayLevelEmphasis" 16.000000 ##
#     7. "GrayLevelNonUniformityNormalized"  9.000000 #
#     8.                       "RunEntropy"  5.000000
#     9.           "GrayLevelNonUniformity"  3.000000
#    10.                  "LongRunEmphasis"  1.000000
#    11. "RunLengthNonUniformityNormalized"  1.000000
#
# Variable Importance: NUM_NODES:
#     1.     "LongRunHighGrayLevelEmphasis" 26964.000000 ################
#     2.           "GrayLevelNonUniformity" 26829.000000 ###############
#     3.                       "RunEntropy" 26462.000000 ###############
#     4.                "GrayLevelVariance" 25166.000000 #############
#     5. "GrayLevelNonUniformityNormalized" 23550.000000 ###########
#     6.     "ShortRunLowGrayLevelEmphasis" 22168.000000 #########
#     7.    "ShortRunHighGrayLevelEmphasis" 21990.000000 ########
#     8.         "HighGrayLevelRunEmphasis" 21917.000000 ########
#     9.      "LongRunLowGrayLevelEmphasis" 21291.000000 #######
#    10.          "LowGrayLevelRunEmphasis" 20510.000000 ######
#    11.                      "RunVariance" 19945.000000 #####
#    12.                 "ShortRunEmphasis" 18773.000000 ####
#    13. "RunLengthNonUniformityNormalized" 18680.000000 ###
#    14.                  "LongRunEmphasis" 17362.000000 ##
#    15.           "RunLengthNonUniformity" 16708.000000 #
#    16.                    "RunPercentage" 15976.000000
#
# Variable Importance: SUM_SCORE:
#     1.     "LongRunHighGrayLevelEmphasis" 899807.505926 ################
#     2.         "HighGrayLevelRunEmphasis" 674670.509282 ###########
#     3.    "ShortRunHighGrayLevelEmphasis" 543330.115762 ########
#     4.     "ShortRunLowGrayLevelEmphasis" 379271.334628 #####
#     5.           "GrayLevelNonUniformity" 343660.184695 ####
#     6.          "LowGrayLevelRunEmphasis" 324130.330675 ####
#     7.                       "RunEntropy" 296897.715118 ###
#     8.      "LongRunLowGrayLevelEmphasis" 278229.624232 ###
#     9. "GrayLevelNonUniformityNormalized" 217759.595733 #
#    10.                 "ShortRunEmphasis" 189164.319640 #
#    11. "RunLengthNonUniformityNormalized" 179246.515072 #
#    12.                      "RunVariance" 175297.784775 #
#    13.                "GrayLevelVariance" 172456.422132 #
#    14.                  "LongRunEmphasis" 134150.082788
#    15.                    "RunPercentage" 125077.077272
#    16.           "RunLengthNonUniformity" 121851.226192
#
#
#
# Winner takes all: true
# Out-of-bag evaluation: accuracy:0.962286 logloss:0.201083
# Number of trees: 300
# Total number of nodes: 688882
#
# Number of nodes by tree:
# Count: 300 Average: 2296.27 StdDev: 136.135
# Min: 1773 Max: 2583 Ignored: 0
# ----------------------------------------------
# [ 1773, 1813)  1   0.33%   0.33%
# [ 1813, 1854)  1   0.33%   0.67%
# [ 1854, 1894)  1   0.33%   1.00%
# [ 1894, 1935)  2   0.67%   1.67% #
# [ 1935, 1975)  1   0.33%   2.00%
# [ 1975, 2016)  5   1.67%   3.67% #
# [ 2016, 2056)  2   0.67%   4.33% #
# [ 2056, 2097)  8   2.67%   7.00% ##
# [ 2097, 2137) 17   5.67%  12.67% ####
# [ 2137, 2178) 18   6.00%  18.67% #####
# [ 2178, 2219) 22   7.33%  26.00% ######
# [ 2219, 2259) 30  10.00%  36.00% ########
# [ 2259, 2300) 36  12.00%  48.00% #########
# [ 2300, 2340) 30  10.00%  58.00% ########
# [ 2340, 2381) 31  10.33%  68.33% ########
# [ 2381, 2421) 39  13.00%  81.33% ##########
# [ 2421, 2462) 30  10.00%  91.33% ########
# [ 2462, 2502) 14   4.67%  96.00% ####
# [ 2502, 2543)  7   2.33%  98.33% ##
# [ 2543, 2583]  5   1.67% 100.00% #
#
# Depth by leafs:
# Count: 344591 Average: 12.4856 StdDev: 2.26625
# Min: 3 Max: 15 Ignored: 0
# ----------------------------------------------
# [  3,  4)    48   0.01%   0.01%
# [  4,  5)   355   0.10%   0.12%
# [  5,  6)  1137   0.33%   0.45%
# [  6,  7)  2684   0.78%   1.23%
# [  7,  8)  5889   1.71%   2.93% #
# [  8,  9) 11027   3.20%   6.13% #
# [  9, 10) 18300   5.31%  11.45% ##
# [ 10, 11) 27748   8.05%  19.50% ###
# [ 11, 12) 37992  11.03%  30.52% ####
# [ 12, 13) 47057  13.66%  44.18% ######
# [ 13, 14) 52934  15.36%  59.54% ######
# [ 14, 15) 54596  15.84%  75.38% ######
# [ 15, 15] 84824  24.62% 100.00% ##########
#
# Number of training obs by leaf:
# Count: 344591 Average: 67.9371 StdDev: 261.46
# Min: 5 Max: 7776 Ignored: 0
# ----------------------------------------------
# [    5,  393) 332234  96.41%  96.41% ##########
# [  393,  782)   6697   1.94%  98.36%
# [  782, 1170)   2232   0.65%  99.01%
# [ 1170, 1559)   1115   0.32%  99.33%
# [ 1559, 1948)    742   0.22%  99.54%
# [ 1948, 2336)    513   0.15%  99.69%
# [ 2336, 2725)    302   0.09%  99.78%
# [ 2725, 3113)    237   0.07%  99.85%
# [ 3113, 3502)    159   0.05%  99.90%
# [ 3502, 3891)    109   0.03%  99.93%
# [ 3891, 4279)     64   0.02%  99.95%
# [ 4279, 4668)     61   0.02%  99.96%
# [ 4668, 5056)     48   0.01%  99.98%
# [ 5056, 5445)     33   0.01%  99.99%
# [ 5445, 5834)     23   0.01%  99.99%
# [ 5834, 6222)     11   0.00% 100.00%
# [ 6222, 6611)      6   0.00% 100.00%
# [ 6611, 6999)      3   0.00% 100.00%
# [ 6999, 7388)      1   0.00% 100.00%
# [ 7388, 7776]      1   0.00% 100.00%
#
# Attribute in nodes:
# 	26964 : LongRunHighGrayLevelEmphasis [NUMERICAL]
# 	26829 : GrayLevelNonUniformity [NUMERICAL]
# 	26462 : RunEntropy [NUMERICAL]
# 	25166 : GrayLevelVariance [NUMERICAL]
# 	23550 : GrayLevelNonUniformityNormalized [NUMERICAL]
# 	22168 : ShortRunLowGrayLevelEmphasis [NUMERICAL]
# 	21990 : ShortRunHighGrayLevelEmphasis [NUMERICAL]
# 	21917 : HighGrayLevelRunEmphasis [NUMERICAL]
# 	21291 : LongRunLowGrayLevelEmphasis [NUMERICAL]
# 	20510 : LowGrayLevelRunEmphasis [NUMERICAL]
# 	19945 : RunVariance [NUMERICAL]
# 	18773 : ShortRunEmphasis [NUMERICAL]
# 	18680 : RunLengthNonUniformityNormalized [NUMERICAL]
# 	17362 : LongRunEmphasis [NUMERICAL]
# 	16708 : RunLengthNonUniformity [NUMERICAL]
# 	15976 : RunPercentage [NUMERICAL]
#
# Attribute in nodes with depth <= 0:
# 	83 : LongRunHighGrayLevelEmphasis [NUMERICAL]
# 	74 : HighGrayLevelRunEmphasis [NUMERICAL]
# 	54 : ShortRunHighGrayLevelEmphasis [NUMERICAL]
# 	33 : ShortRunLowGrayLevelEmphasis [NUMERICAL]
# 	21 : LowGrayLevelRunEmphasis [NUMERICAL]
# 	16 : LongRunLowGrayLevelEmphasis [NUMERICAL]
# 	9 : GrayLevelNonUniformityNormalized [NUMERICAL]
# 	5 : RunEntropy [NUMERICAL]
# 	3 : GrayLevelNonUniformity [NUMERICAL]
# 	1 : RunLengthNonUniformityNormalized [NUMERICAL]
# 	1 : LongRunEmphasis [NUMERICAL]
#
# Attribute in nodes with depth <= 1:
# 	231 : LongRunHighGrayLevelEmphasis [NUMERICAL]
# 	166 : HighGrayLevelRunEmphasis [NUMERICAL]
# 	134 : ShortRunHighGrayLevelEmphasis [NUMERICAL]
# 	102 : ShortRunLowGrayLevelEmphasis [NUMERICAL]
# 	78 : LowGrayLevelRunEmphasis [NUMERICAL]
# 	77 : LongRunLowGrayLevelEmphasis [NUMERICAL]
# 	30 : ShortRunEmphasis [NUMERICAL]
# 	26 : RunLengthNonUniformityNormalized [NUMERICAL]
# 	18 : GrayLevelNonUniformityNormalized [NUMERICAL]
# 	12 : RunEntropy [NUMERICAL]
# 	11 : GrayLevelNonUniformity [NUMERICAL]
# 	6 : RunVariance [NUMERICAL]
# 	4 : LongRunEmphasis [NUMERICAL]
# 	3 : RunPercentage [NUMERICAL]
# 	2 : RunLengthNonUniformity [NUMERICAL]
#
# Attribute in nodes with depth <= 2:
# 	485 : LongRunHighGrayLevelEmphasis [NUMERICAL]
# 	294 : HighGrayLevelRunEmphasis [NUMERICAL]
# 	263 : ShortRunHighGrayLevelEmphasis [NUMERICAL]
# 	201 : ShortRunLowGrayLevelEmphasis [NUMERICAL]
# 	161 : LowGrayLevelRunEmphasis [NUMERICAL]
# 	126 : LongRunLowGrayLevelEmphasis [NUMERICAL]
# 	96 : ShortRunEmphasis [NUMERICAL]
# 	91 : RunLengthNonUniformityNormalized [NUMERICAL]
# 	82 : GrayLevelNonUniformity [NUMERICAL]
# 	55 : RunEntropy [NUMERICAL]
# 	54 : GrayLevelNonUniformityNormalized [NUMERICAL]
# 	49 : RunVariance [NUMERICAL]
# 	44 : GrayLevelVariance [NUMERICAL]
# 	35 : LongRunEmphasis [NUMERICAL]
# 	34 : RunLengthNonUniformity [NUMERICAL]
# 	30 : RunPercentage [NUMERICAL]
#
# Attribute in nodes with depth <= 3:
# 	842 : LongRunHighGrayLevelEmphasis [NUMERICAL]
# 	481 : HighGrayLevelRunEmphasis [NUMERICAL]
# 	447 : ShortRunHighGrayLevelEmphasis [NUMERICAL]
# 	321 : ShortRunLowGrayLevelEmphasis [NUMERICAL]
# 	303 : LowGrayLevelRunEmphasis [NUMERICAL]
# 	279 : GrayLevelNonUniformity [NUMERICAL]
# 	268 : LongRunLowGrayLevelEmphasis [NUMERICAL]
# 	233 : RunEntropy [NUMERICAL]
# 	209 : RunLengthNonUniformityNormalized [NUMERICAL]
# 	196 : ShortRunEmphasis [NUMERICAL]
# 	193 : GrayLevelNonUniformityNormalized [NUMERICAL]
# 	179 : GrayLevelVariance [NUMERICAL]
# 	140 : RunVariance [NUMERICAL]
# 	122 : LongRunEmphasis [NUMERICAL]
# 	121 : RunPercentage [NUMERICAL]
# 	118 : RunLengthNonUniformity [NUMERICAL]
#
# Attribute in nodes with depth <= 5:
# 	2157 : LongRunHighGrayLevelEmphasis [NUMERICAL]
# 	1407 : RunEntropy [NUMERICAL]
# 	1272 : GrayLevelNonUniformity [NUMERICAL]
# 	1237 : HighGrayLevelRunEmphasis [NUMERICAL]
# 	1168 : ShortRunHighGrayLevelEmphasis [NUMERICAL]
# 	1077 : ShortRunLowGrayLevelEmphasis [NUMERICAL]
# 	990 : LowGrayLevelRunEmphasis [NUMERICAL]
# 	937 : GrayLevelNonUniformityNormalized [NUMERICAL]
# 	918 : GrayLevelVariance [NUMERICAL]
# 	874 : RunLengthNonUniformityNormalized [NUMERICAL]
# 	857 : LongRunLowGrayLevelEmphasis [NUMERICAL]
# 	842 : ShortRunEmphasis [NUMERICAL]
# 	781 : RunVariance [NUMERICAL]
# 	626 : LongRunEmphasis [NUMERICAL]
# 	614 : RunLengthNonUniformity [NUMERICAL]
# 	605 : RunPercentage [NUMERICAL]
#
# Condition type in nodes:
# 	344291 : HigherCondition
# Condition type in nodes with depth <= 0:
# 	300 : HigherCondition
# Condition type in nodes with depth <= 1:
# 	900 : HigherCondition
# Condition type in nodes with depth <= 2:
# 	2100 : HigherCondition
# Condition type in nodes with depth <= 3:
# 	4452 : HigherCondition
# Condition type in nodes with depth <= 5:
# 	16362 : HigherCondition
# Node format: NOT_SET
#
# Training OOB:
# 	trees: 1, Out-of-bag evaluation: accuracy:0.948236 logloss:1.86578
# 	trees: 11, Out-of-bag evaluation: accuracy:0.957851 logloss:0.812466
# 	trees: 21, Out-of-bag evaluation: accuracy:0.960246 logloss:0.558614
# 	trees: 31, Out-of-bag evaluation: accuracy:0.961094 logloss:0.453785
# 	trees: 41, Out-of-bag evaluation: accuracy:0.961492 logloss:0.405505
# 	trees: 51, Out-of-bag evaluation: accuracy:0.961786 logloss:0.370541
# 	trees: 61, Out-of-bag evaluation: accuracy:0.961825 logloss:0.350723
# 	trees: 71, Out-of-bag evaluation: accuracy:0.961966 logloss:0.332879
# 	trees: 81, Out-of-bag evaluation: accuracy:0.96185 logloss:0.313501
# 	trees: 91, Out-of-bag evaluation: accuracy:0.962017 logloss:0.29495
# 	trees: 101, Out-of-bag evaluation: accuracy:0.961927 logloss:0.284158
# 	trees: 111, Out-of-bag evaluation: accuracy:0.962081 logloss:0.275061
# 	trees: 121, Out-of-bag evaluation: accuracy:0.962056 logloss:0.265638
# 	trees: 131, Out-of-bag evaluation: accuracy:0.962222 logloss:0.25709
# 	trees: 141, Out-of-bag evaluation: accuracy:0.962427 logloss:0.25044
# 	trees: 151, Out-of-bag evaluation: accuracy:0.962299 logloss:0.244151
# 	trees: 161, Out-of-bag evaluation: accuracy:0.962337 logloss:0.239257
# 	trees: 171, Out-of-bag evaluation: accuracy:0.962184 logloss:0.234293
# 	trees: 181, Out-of-bag evaluation: accuracy:0.962248 logloss:0.229465
# 	trees: 191, Out-of-bag evaluation: accuracy:0.962261 logloss:0.225871
# 	trees: 201, Out-of-bag evaluation: accuracy:0.962312 logloss:0.222658
# 	trees: 211, Out-of-bag evaluation: accuracy:0.962261 logloss:0.219443
# 	trees: 221, Out-of-bag evaluation: accuracy:0.962286 logloss:0.215329
# 	trees: 231, Out-of-bag evaluation: accuracy:0.962248 logloss:0.212896
# 	trees: 241, Out-of-bag evaluation: accuracy:0.962196 logloss:0.210853
# 	trees: 251, Out-of-bag evaluation: accuracy:0.962196 logloss:0.208797
# 	trees: 261, Out-of-bag evaluation: accuracy:0.962273 logloss:0.207143
# 	trees: 271, Out-of-bag evaluation: accuracy:0.962389 logloss:0.205608
# 	trees: 281, Out-of-bag evaluation: accuracy:0.962466 logloss:0.204393
# 	trees: 291, Out-of-bag evaluation: accuracy:0.962261 logloss:0.203132
# 	trees: 300, Out-of-bag evaluation: accuracy:0.962286 logloss:0.201083

# %%
# Model features
model.make_inspector().features()
# Out:
# ["GrayLevelNonUniformity" (1; #0),
#  "GrayLevelNonUniformityNormalized" (1; #1),
#  "GrayLevelVariance" (1; #2),
#  "HighGrayLevelRunEmphasis" (1; #3),
#  "LongRunEmphasis" (1; #4),
#  "LongRunHighGrayLevelEmphasis" (1; #5),
#  "LongRunLowGrayLevelEmphasis" (1; #6),
#  "LowGrayLevelRunEmphasis" (1; #7),
#  "RunEntropy" (1; #8),
#  "RunLengthNonUniformity" (1; #9),
#  "RunLengthNonUniformityNormalized" (1; #10),
#  "RunPercentage" (1; #11),
#  "RunVariance" (1; #12),
#  "ShortRunEmphasis" (1; #13),
#  "ShortRunHighGrayLevelEmphasis" (1; #14),
#  "ShortRunLowGrayLevelEmphasis" (1; #15)]

# %%
# Feature importance
model.make_inspector().variable_importances()
# Out:
# {'INV_MEAN_MIN_DEPTH': [("LongRunHighGrayLevelEmphasis" (1; #5),
#    0.20743615989847505),
#   ("HighGrayLevelRunEmphasis" (1; #3), 0.15331229520500195),
#   ("ShortRunHighGrayLevelEmphasis" (1; #14), 0.13886946981059015),
#   ("ShortRunLowGrayLevelEmphasis" (1; #15), 0.11909344458555832),
#   ("LowGrayLevelRunEmphasis" (1; #7), 0.11686945017599852),
#   ("GrayLevelNonUniformity" (1; #0), 0.11443964769131554),
#   ("LongRunLowGrayLevelEmphasis" (1; #6), 0.11316606573916749),
#   ("RunEntropy" (1; #8), 0.11006138751426346),
#   ("ShortRunEmphasis" (1; #13), 0.10597741241363064),
#   ("RunLengthNonUniformityNormalized" (1; #10), 0.10596562029990536),
#   ("GrayLevelNonUniformityNormalized" (1; #1), 0.09925331942084703),
#   ("RunVariance" (1; #12), 0.09318123200137648),
#   ("GrayLevelVariance" (1; #2), 0.08922464603325475),
#   ("LongRunEmphasis" (1; #4), 0.08808940862547632),
#   ("RunLengthNonUniformity" (1; #9), 0.0869353722518901),
#   ("RunPercentage" (1; #11), 0.08657677238373818)],
#  'NUM_AS_ROOT': [("LongRunHighGrayLevelEmphasis" (1; #5), 83.0),
#   ("HighGrayLevelRunEmphasis" (1; #3), 74.0),
#   ("ShortRunHighGrayLevelEmphasis" (1; #14), 54.0),
#   ("ShortRunLowGrayLevelEmphasis" (1; #15), 33.0),
#   ("LowGrayLevelRunEmphasis" (1; #7), 21.0),
#   ("LongRunLowGrayLevelEmphasis" (1; #6), 16.0),
#   ("GrayLevelNonUniformityNormalized" (1; #1), 9.0),
#   ("RunEntropy" (1; #8), 5.0),
#   ("GrayLevelNonUniformity" (1; #0), 3.0),
#   ("LongRunEmphasis" (1; #4), 1.0),
#   ("RunLengthNonUniformityNormalized" (1; #10), 1.0)],
#  'SUM_SCORE': [("LongRunHighGrayLevelEmphasis" (1; #5), 899807.5059262454),
#   ("HighGrayLevelRunEmphasis" (1; #3), 674670.5092823128),
#   ("ShortRunHighGrayLevelEmphasis" (1; #14), 543330.1157623305),
#   ("ShortRunLowGrayLevelEmphasis" (1; #15), 379271.33462755743),
#   ("GrayLevelNonUniformity" (1; #0), 343660.1846952044),
#   ("LowGrayLevelRunEmphasis" (1; #7), 324130.3306751403),
#   ("RunEntropy" (1; #8), 296897.71511790995),
#   ("LongRunLowGrayLevelEmphasis" (1; #6), 278229.6242319162),
#   ("GrayLevelNonUniformityNormalized" (1; #1), 217759.5957331379),
#   ("ShortRunEmphasis" (1; #13), 189164.31963977215),
#   ("RunLengthNonUniformityNormalized" (1; #10), 179246.51507173423),
#   ("RunVariance" (1; #12), 175297.78477539276),
#   ("GrayLevelVariance" (1; #2), 172456.42213150143),
#   ("LongRunEmphasis" (1; #4), 134150.0827879311),
#   ("RunPercentage" (1; #11), 125077.0772721655),
#   ("RunLengthNonUniformity" (1; #9), 121851.22619161359)],
#  'NUM_NODES': [("LongRunHighGrayLevelEmphasis" (1; #5), 26964.0),
#   ("GrayLevelNonUniformity" (1; #0), 26829.0),
#   ("RunEntropy" (1; #8), 26462.0),
#   ("GrayLevelVariance" (1; #2), 25166.0),
#   ("GrayLevelNonUniformityNormalized" (1; #1), 23550.0),
#   ("ShortRunLowGrayLevelEmphasis" (1; #15), 22168.0),
#   ("ShortRunHighGrayLevelEmphasis" (1; #14), 21990.0),
#   ("HighGrayLevelRunEmphasis" (1; #3), 21917.0),
#   ("LongRunLowGrayLevelEmphasis" (1; #6), 21291.0),
#   ("LowGrayLevelRunEmphasis" (1; #7), 20510.0),
#   ("RunVariance" (1; #12), 19945.0),
#   ("ShortRunEmphasis" (1; #13), 18773.0),
#   ("RunLengthNonUniformityNormalized" (1; #10), 18680.0),
#   ("LongRunEmphasis" (1; #4), 17362.0),
#   ("RunLengthNonUniformity" (1; #9), 16708.0),
#   ("RunPercentage" (1; #11), 15976.0)]}

# %%
# Model self evaluation
model.make_inspector().evaluation()
# Out:
# Evaluation(num_examples=78035, accuracy=0.9622861536490036, loss=0.20108282324762114, rmse=None, ndcg=None, aucs=None, auuc=None, qini=None)

# %%
logs = model.make_inspector().training_logs()

plt.figure(figsize=(12, 4))
plt.subplot(1, 2, 1)
plt.plot([log.num_trees for log in logs], [log.evaluation.accuracy for log in logs])
plt.xlabel("Number of trees")
plt.ylabel("Accuracy (out-of-bag)")
plt.subplot(1, 2, 2)
plt.plot([log.num_trees for log in logs], [log.evaluation.loss for log in logs])
plt.xlabel("Number of trees")
plt.ylabel("Logloss (out-of-bag)")
plt.show()

# %% [markdown]
# Calculate the score of our hold-out validation dataset

# %%
predictions = model.predict(val_ds)
y_true      = validation_data["label"]

from sklearn.metrics import roc_auc_score
ROC_AUC = roc_auc_score(y_true, predictions)
print("The ROC AUC score is %.5f" % ROC_AUC )
# Out:
# 12/12 [==============================] - 1s 41ms/step
# The ROC AUC score is 0.95661

# %%
# Compute binary classification metrics with sklearn
import numpy as np
from sklearn.metrics import (
    accuracy_score,
    precision_score,
    recall_score,
    f1_score,
    roc_auc_score,
    average_precision_score,
    confusion_matrix,
    classification_report,
    matthews_corrcoef,
    log_loss,
    brier_score_loss,
)

# Get predictions (probabilities or class labels)
preds = model.predict(test_ds)
# If model outputs probabilities, convert to labels by threshold 0.5
if preds.ndim == 2:
    # For TFDF classification, preds may be class probabilities with shape (N, 2)
    if preds.shape[1] == 2:
        pos_probs = preds[:, 1]
    else:
        # If single-probability column (positive class)
        pos_probs = preds[:, -1]
    y_pred = (pos_probs >= 0.5).astype(int)
else:
    # Already class labels
    y_pred = preds.astype(int)
    pos_probs = None

# Ground truth labels (must be 0/1 integers)
y_true = test_data["label"].astype(int).to_numpy()

# Core metrics
metrics = {}
metrics["accuracy"] = accuracy_score(y_true, y_pred)
metrics["precision"] = precision_score(y_true, y_pred, zero_division=0)
metrics["recall"] = recall_score(y_true, y_pred, zero_division=0)
metrics["f1"] = f1_score(y_true, y_pred, zero_division=0)
metrics["mcc"] = matthews_corrcoef(y_true, y_pred)

# Probabilistic metrics (only if we have probabilities)
if pos_probs is not None:
    metrics["roc_auc"] = roc_auc_score(y_true, pos_probs)
    metrics["pr_auc"] = average_precision_score(y_true, pos_probs)
    metrics["log_loss"] = log_loss(y_true, pos_probs, labels=[0,1])
    metrics["brier_score"] = brier_score_loss(y_true, pos_probs)

# Confusion matrix and detailed report
cm = confusion_matrix(y_true, y_pred, labels=[0,1])
report = classification_report(y_true, y_pred, digits=4)

print("Sklearn binary metrics:")
for k, v in metrics.items():
    print(f"{k}: {v:.4f}")
print("\nConfusion matrix:\n", cm)
print("\nClassification report:\n", report)
# Out:
# 23/23 [==============================] - 1s 55ms/step
# Sklearn binary metrics:
# accuracy: 0.9651
# precision: 0.8638
# recall: 0.6000
# f1: 0.7081
# mcc: 0.7032
# roc_auc: 0.9587
# pr_auc: 0.8004
# log_loss: 0.1128
# brier_score: 0.0277
#
# Confusion matrix:
#  [[20572   149]
#  [  630   945]]
#
# Classification report:
#                precision    recall  f1-score   support
#
#            0     0.9703    0.9928    0.9814     20721
#            1     0.8638    0.6000    0.7081      1575
#
#     accuracy                         0.9651     22296
#    macro avg     0.9170    0.7964    0.8448     22296
# weighted avg     0.9628    0.9651    0.9621     22296
