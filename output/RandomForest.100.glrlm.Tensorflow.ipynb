# %%
# Import packages and modules
import numpy  as np
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow_decision_forests as tfdf

from sklearn.model_selection import train_test_split
# Out:
# 2026-07-04 08:54:09.379775: I tensorflow/core/util/port.cc:113] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2026-07-04 08:54:09.419609: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2026-07-04 08:54:13.766163: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
# Check the version of TensorFlow Decision Forests
print("Found TensorFlow Decision Forests v" + tfdf.__version__)
# Out:
# Found TensorFlow Decision Forests v1.9.1

# %%
datasetPath = 'dataset/firstorder/kernel5-radius5/dataset.csv'

# %%
# Parameters
datasetPath = "dataset/glrlm/kernel5-radius5/100.dataset.csv"

# %%
# train/validation/test = 70/10/20
dataset = pd.read_csv(datasetPath)

train_data, temp_data = train_test_split(dataset, test_size=0.3, random_state=42)
validation_data, test_data = train_test_split(temp_data, test_size=2/3, random_state=42)

# %%
from sklearn.utils.class_weight import compute_class_weight

# tinh class weight tren tap train
classes = np.array([0, 1])
weights = compute_class_weight(class_weight="balanced", classes=classes, y=train_data["label"])
class_weight = {0: weights[0], 1: weights[1]}

# gan sample_weight cho tung dong
train_data["sample_weight"] = train_data["label"].map(class_weight)
validation_data["sample_weight"] = validation_data["label"].map(class_weight)
test_data["sample_weight"] = test_data["label"].map(class_weight)

# Convert the dataset into a TensorFlow dataset.
train_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    train_data, label="label", weight="sample_weight"
)         
val_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    validation_data, label="label", weight="sample_weight"
)
test_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    test_data, label="label", weight="sample_weight"
)
# Out:
# 2026-07-04 08:54:27.293443: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:984] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2026-07-04 08:54:27.294602: W tensorflow/core/common_runtime/gpu/gpu_device.cc:2251] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...

# %%
import keras

# %%
# %%time

# Train a Random Forest model.
model = tfdf.keras.RandomForestModel()

# Add evaluation metrics
model.compile(
    metrics=["accuracy"]
)
model.fit(x=train_ds)

# # Train a Gradient Boosted Trees model.
# model = tfdf.keras.GradientBoostedTreesModel(num_trees=1500)
# model.fit(train_ds)
# Out:
# Use /tmp/tmpts3mw1wg as temporary training directory
# Reading training dataset...
# Training dataset read in 0:00:02.762834. Found 78790 examples.
# Training model...
# [INFO 26-07-04 08:54:37.0680 UTC kernel.cc:1233] Loading model from path /tmp/tmpts3mw1wg/model/ with prefix 0f61f919b69b4358
# Model trained in 0:00:07.778450
# Compiling model...
# [INFO 26-07-04 08:54:37.8775 UTC decision_forest.cc:734] Model loaded with 300 root(s), 690786 node(s), and 16 input feature(s).
# [INFO 26-07-04 08:54:37.8776 UTC abstract_model.cc:1362] Engine "RandomForestOptPred" built
# [INFO 26-07-04 08:54:37.8776 UTC kernel.cc:1061] Use fast generic engine
# Model compiled.
# CPU times: user 1min 25s, sys: 969 ms, total: 1min 26s
# Wall time: 13.7 s

# %%
# Evaluate the model
evaluate = model.evaluate(val_ds, return_dict=True)
print()

for name, value in evaluate.items():
    print(f"{name}: {value:.4f}")
# Out:
# WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
#  1/12 [=>............................] - ETA: 32s - loss: 0.0000e+00 - accuracy: 0.9560
#  3/12 [======>.......................] - ETA: 0s - loss: 0.0000e+00 - accuracy: 0.9507
#  5/12 [===========>..................] - ETA: 0s - loss: 0.0000e+00 - accuracy: 0.9498
#  7/12 [================>.............] - ETA: 0s - loss: 0.0000e+00 - accuracy: 0.9491
#  9/12 [=====================>........] - ETA: 0s - loss: 0.0000e+00 - accuracy: 0.9489
# 11/12 [==========================>...] - ETA: 0s - loss: 0.0000e+00 - accuracy: 0.9482
# 12/12 [==============================] - 3s 28ms/step - loss: 0.0000e+00 - accuracy: 0.9481
# loss: 0.0000
# accuracy: 0.9481

# %%
# Model Summary
model.summary()
# Out:
# Model: "random_forest_model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
# =================================================================
# Total params: 1 (1.00 Byte)
# Trainable params: 0 (0.00 Byte)
# Non-trainable params: 1 (1.00 Byte)
# _________________________________________________________________
# Type: "RANDOM_FOREST"
# Task: CLASSIFICATION
# Label: "__LABEL"
#
# Input Features (16):
# 	GrayLevelNonUniformity
# 	GrayLevelNonUniformityNormalized
# 	GrayLevelVariance
# 	HighGrayLevelRunEmphasis
# 	LongRunEmphasis
# 	LongRunHighGrayLevelEmphasis
# 	LongRunLowGrayLevelEmphasis
# 	LowGrayLevelRunEmphasis
# 	RunEntropy
# 	RunLengthNonUniformity
# 	RunLengthNonUniformityNormalized
# 	RunPercentage
# 	RunVariance
# 	ShortRunEmphasis
# 	ShortRunHighGrayLevelEmphasis
# 	ShortRunLowGrayLevelEmphasis
#
# Trained with weights
#
# Variable Importance: INV_MEAN_MIN_DEPTH:
#     1.     "LongRunHighGrayLevelEmphasis"  0.199543 ################
#     2.         "HighGrayLevelRunEmphasis"  0.148498 ########
#     3.    "ShortRunHighGrayLevelEmphasis"  0.135282 ######
#     4.          "LowGrayLevelRunEmphasis"  0.119041 ####
#     5.           "GrayLevelNonUniformity"  0.117036 ####
#     6.      "LongRunLowGrayLevelEmphasis"  0.112915 ###
#     7.                       "RunEntropy"  0.111300 ###
#     8.     "ShortRunLowGrayLevelEmphasis"  0.108725 ##
#     9. "RunLengthNonUniformityNormalized"  0.108527 ##
#    10.                 "ShortRunEmphasis"  0.106512 ##
#    11. "GrayLevelNonUniformityNormalized"  0.100801 #
#    12.                "GrayLevelVariance"  0.092962
#    13.                      "RunVariance"  0.092006
#    14.           "RunLengthNonUniformity"  0.091904
#    15.                  "LongRunEmphasis"  0.089514
#    16.                    "RunPercentage"  0.087845
#
# Variable Importance: NUM_AS_ROOT:
#     1.     "LongRunHighGrayLevelEmphasis" 97.000000 ################
#     2.         "HighGrayLevelRunEmphasis" 68.000000 ###########
#     3.    "ShortRunHighGrayLevelEmphasis" 42.000000 ######
#     4.          "LowGrayLevelRunEmphasis" 32.000000 #####
#     5.      "LongRunLowGrayLevelEmphasis" 21.000000 ###
#     6.     "ShortRunLowGrayLevelEmphasis" 19.000000 ###
#     7.           "GrayLevelNonUniformity"  8.000000 #
#     8. "GrayLevelNonUniformityNormalized"  8.000000 #
#     9.                       "RunEntropy"  2.000000
#    10.           "RunLengthNonUniformity"  1.000000
#    11.                      "RunVariance"  1.000000
#    12.                 "ShortRunEmphasis"  1.000000
#
# Variable Importance: NUM_NODES:
#     1.                       "RunEntropy" 27183.000000 ################
#     2.           "GrayLevelNonUniformity" 27172.000000 ###############
#     3.     "LongRunHighGrayLevelEmphasis" 26767.000000 ###############
#     4.                "GrayLevelVariance" 25678.000000 #############
#     5. "GrayLevelNonUniformityNormalized" 23634.000000 ##########
#     6.     "ShortRunLowGrayLevelEmphasis" 21783.000000 ########
#     7.    "ShortRunHighGrayLevelEmphasis" 21749.000000 ########
#     8.         "HighGrayLevelRunEmphasis" 21526.000000 #######
#     9.      "LongRunLowGrayLevelEmphasis" 21261.000000 #######
#    10.          "LowGrayLevelRunEmphasis" 20566.000000 ######
#    11.                      "RunVariance" 20142.000000 #####
#    12.                 "ShortRunEmphasis" 18672.000000 ###
#    13. "RunLengthNonUniformityNormalized" 18659.000000 ###
#    14.                  "LongRunEmphasis" 17609.000000 ##
#    15.           "RunLengthNonUniformity" 16775.000000 #
#    16.                    "RunPercentage" 16067.000000
#
# Variable Importance: SUM_SCORE:
#     1.     "LongRunHighGrayLevelEmphasis" 2484748.955991 ################
#     2.         "HighGrayLevelRunEmphasis" 1680344.933443 #########
#     3.    "ShortRunHighGrayLevelEmphasis" 1314700.044070 #######
#     4.          "LowGrayLevelRunEmphasis" 1087347.768743 #####
#     5.           "GrayLevelNonUniformity" 1018207.491575 ####
#     6.                       "RunEntropy" 942592.327932 ####
#     7.      "LongRunLowGrayLevelEmphasis" 924075.530259 ####
#     8.     "ShortRunLowGrayLevelEmphasis" 846490.153894 ###
#     9. "RunLengthNonUniformityNormalized" 639435.823873 ##
#    10.                 "ShortRunEmphasis" 622959.189800 #
#    11. "GrayLevelNonUniformityNormalized" 619615.847573 #
#    12.                "GrayLevelVariance" 541294.316057 #
#    13.                      "RunVariance" 460530.902522
#    14.                  "LongRunEmphasis" 414153.080557
#    15.           "RunLengthNonUniformity" 409983.951558
#    16.                    "RunPercentage" 370826.533857
#
#
#
# Winner takes all: true
# Out-of-bag evaluation: accuracy:0.862714 logloss:0.470428
# Number of trees: 300
# Total number of nodes: 690786
#
# Number of nodes by tree:
# Count: 300 Average: 2302.62 StdDev: 113.9
# Min: 1897 Max: 2595 Ignored: 0
# ----------------------------------------------
# [ 1897, 1931)  1   0.33%   0.33%
# [ 1931, 1966)  0   0.00%   0.33%
# [ 1966, 2001)  0   0.00%   0.33%
# [ 2001, 2036)  2   0.67%   1.00% #
# [ 2036, 2071)  4   1.33%   2.33% #
# [ 2071, 2106) 10   3.33%   5.67% ###
# [ 2106, 2141)  9   3.00%   8.67% ##
# [ 2141, 2176) 13   4.33%  13.00% ###
# [ 2176, 2211) 28   9.33%  22.33% #######
# [ 2211, 2246) 24   8.00%  30.33% ######
# [ 2246, 2281) 29   9.67%  40.00% #######
# [ 2281, 2316) 33  11.00%  51.00% ########
# [ 2316, 2351) 39  13.00%  64.00% ##########
# [ 2351, 2386) 35  11.67%  75.67% #########
# [ 2386, 2421) 32  10.67%  86.33% ########
# [ 2421, 2456) 17   5.67%  92.00% ####
# [ 2456, 2491) 13   4.33%  96.33% ###
# [ 2491, 2526)  4   1.33%  97.67% #
# [ 2526, 2561)  4   1.33%  99.00% #
# [ 2561, 2595]  3   1.00% 100.00% #
#
# Depth by leafs:
# Count: 345543 Average: 12.4246 StdDev: 2.286
# Min: 3 Max: 15 Ignored: 0
# ----------------------------------------------
# [  3,  4)     7   0.00%   0.00%
# [  4,  5)   281   0.08%   0.08%
# [  5,  6)  1029   0.30%   0.38%
# [  6,  7)  2874   0.83%   1.21%
# [  7,  8)  6217   1.80%   3.01% #
# [  8,  9) 11783   3.41%   6.42% #
# [  9, 10) 19783   5.73%  12.15% ##
# [ 10, 11) 29434   8.52%  20.67% ####
# [ 11, 12) 38853  11.24%  31.91% #####
# [ 12, 13) 46856  13.56%  45.47% ######
# [ 13, 14) 51854  15.01%  60.48% ######
# [ 14, 15) 52796  15.28%  75.76% ######
# [ 15, 15] 83776  24.24% 100.00% ##########
#
# Number of training obs by leaf:
# Count: 345543 Average: 68.4054 StdDev: 270.655
# Min: 5 Max: 8138 Ignored: 0
# ----------------------------------------------
# [    5,  411) 334462  96.79%  96.79% ##########
# [  411,  818)   6096   1.76%  98.56%
# [  818, 1225)   1975   0.57%  99.13%
# [ 1225, 1631)    923   0.27%  99.40%
# [ 1631, 2038)    570   0.16%  99.56%
# [ 2038, 2445)    388   0.11%  99.67%
# [ 2445, 2851)    280   0.08%  99.75%
# [ 2851, 3258)    251   0.07%  99.83%
# [ 3258, 3665)    209   0.06%  99.89%
# [ 3665, 4072)    122   0.04%  99.92%
# [ 4072, 4478)     72   0.02%  99.94%
# [ 4478, 4885)     61   0.02%  99.96%
# [ 4885, 5292)     39   0.01%  99.97%
# [ 5292, 5698)     36   0.01%  99.98%
# [ 5698, 6105)     20   0.01%  99.99%
# [ 6105, 6512)     18   0.01%  99.99%
# [ 6512, 6918)     15   0.00% 100.00%
# [ 6918, 7325)      3   0.00% 100.00%
# [ 7325, 7732)      1   0.00% 100.00%
# [ 7732, 8138]      2   0.00% 100.00%
#
# Attribute in nodes:
# 	27183 : RunEntropy [NUMERICAL]
# 	27172 : GrayLevelNonUniformity [NUMERICAL]
# 	26767 : LongRunHighGrayLevelEmphasis [NUMERICAL]
# 	25678 : GrayLevelVariance [NUMERICAL]
# 	23634 : GrayLevelNonUniformityNormalized [NUMERICAL]
# 	21783 : ShortRunLowGrayLevelEmphasis [NUMERICAL]
# 	21749 : ShortRunHighGrayLevelEmphasis [NUMERICAL]
# 	21526 : HighGrayLevelRunEmphasis [NUMERICAL]
# 	21261 : LongRunLowGrayLevelEmphasis [NUMERICAL]
# 	20566 : LowGrayLevelRunEmphasis [NUMERICAL]
# 	20142 : RunVariance [NUMERICAL]
# 	18672 : ShortRunEmphasis [NUMERICAL]
# 	18659 : RunLengthNonUniformityNormalized [NUMERICAL]
# 	17609 : LongRunEmphasis [NUMERICAL]
# 	16775 : RunLengthNonUniformity [NUMERICAL]
# 	16067 : RunPercentage [NUMERICAL]
#
# Attribute in nodes with depth <= 0:
# 	97 : LongRunHighGrayLevelEmphasis [NUMERICAL]
# 	68 : HighGrayLevelRunEmphasis [NUMERICAL]
# 	42 : ShortRunHighGrayLevelEmphasis [NUMERICAL]
# 	32 : LowGrayLevelRunEmphasis [NUMERICAL]
# 	21 : LongRunLowGrayLevelEmphasis [NUMERICAL]
# 	19 : ShortRunLowGrayLevelEmphasis [NUMERICAL]
# 	8 : GrayLevelNonUniformityNormalized [NUMERICAL]
# 	8 : GrayLevelNonUniformity [NUMERICAL]
# 	2 : RunEntropy [NUMERICAL]
# 	1 : ShortRunEmphasis [NUMERICAL]
# 	1 : RunVariance [NUMERICAL]
# 	1 : RunLengthNonUniformity [NUMERICAL]
#
# Attribute in nodes with depth <= 1:
# 	221 : LongRunHighGrayLevelEmphasis [NUMERICAL]
# 	176 : HighGrayLevelRunEmphasis [NUMERICAL]
# 	136 : ShortRunHighGrayLevelEmphasis [NUMERICAL]
# 	71 : LowGrayLevelRunEmphasis [NUMERICAL]
# 	68 : LongRunLowGrayLevelEmphasis [NUMERICAL]
# 	63 : ShortRunLowGrayLevelEmphasis [NUMERICAL]
# 	57 : RunLengthNonUniformityNormalized [NUMERICAL]
# 	42 : ShortRunEmphasis [NUMERICAL]
# 	18 : RunLengthNonUniformity [NUMERICAL]
# 	14 : GrayLevelNonUniformity [NUMERICAL]
# 	12 : GrayLevelVariance [NUMERICAL]
# 	12 : GrayLevelNonUniformityNormalized [NUMERICAL]
# 	4 : RunVariance [NUMERICAL]
# 	4 : RunEntropy [NUMERICAL]
# 	2 : RunPercentage [NUMERICAL]
#
# Attribute in nodes with depth <= 2:
# 	480 : LongRunHighGrayLevelEmphasis [NUMERICAL]
# 	312 : HighGrayLevelRunEmphasis [NUMERICAL]
# 	240 : ShortRunHighGrayLevelEmphasis [NUMERICAL]
# 	211 : LowGrayLevelRunEmphasis [NUMERICAL]
# 	171 : ShortRunLowGrayLevelEmphasis [NUMERICAL]
# 	151 : LongRunLowGrayLevelEmphasis [NUMERICAL]
# 	98 : GrayLevelNonUniformity [NUMERICAL]
# 	85 : RunLengthNonUniformityNormalized [NUMERICAL]
# 	78 : GrayLevelNonUniformityNormalized [NUMERICAL]
# 	69 : ShortRunEmphasis [NUMERICAL]
# 	67 : RunEntropy [NUMERICAL]
# 	36 : GrayLevelVariance [NUMERICAL]
# 	31 : RunVariance [NUMERICAL]
# 	30 : RunLengthNonUniformity [NUMERICAL]
# 	24 : LongRunEmphasis [NUMERICAL]
# 	17 : RunPercentage [NUMERICAL]
#
# Attribute in nodes with depth <= 3:
# 	876 : LongRunHighGrayLevelEmphasis [NUMERICAL]
# 	499 : HighGrayLevelRunEmphasis [NUMERICAL]
# 	390 : ShortRunHighGrayLevelEmphasis [NUMERICAL]
# 	359 : LowGrayLevelRunEmphasis [NUMERICAL]
# 	304 : GrayLevelNonUniformity [NUMERICAL]
# 	300 : ShortRunLowGrayLevelEmphasis [NUMERICAL]
# 	287 : LongRunLowGrayLevelEmphasis [NUMERICAL]
# 	252 : RunEntropy [NUMERICAL]
# 	209 : ShortRunEmphasis [NUMERICAL]
# 	209 : GrayLevelNonUniformityNormalized [NUMERICAL]
# 	198 : RunLengthNonUniformityNormalized [NUMERICAL]
# 	152 : RunVariance [NUMERICAL]
# 	141 : GrayLevelVariance [NUMERICAL]
# 	120 : LongRunEmphasis [NUMERICAL]
# 	106 : RunLengthNonUniformity [NUMERICAL]
# 	91 : RunPercentage [NUMERICAL]
#
# Attribute in nodes with depth <= 5:
# 	2259 : LongRunHighGrayLevelEmphasis [NUMERICAL]
# 	1512 : RunEntropy [NUMERICAL]
# 	1397 : GrayLevelNonUniformity [NUMERICAL]
# 	1196 : HighGrayLevelRunEmphasis [NUMERICAL]
# 	1078 : LowGrayLevelRunEmphasis [NUMERICAL]
# 	1062 : ShortRunHighGrayLevelEmphasis [NUMERICAL]
# 	997 : ShortRunLowGrayLevelEmphasis [NUMERICAL]
# 	979 : GrayLevelNonUniformityNormalized [NUMERICAL]
# 	959 : LongRunLowGrayLevelEmphasis [NUMERICAL]
# 	935 : ShortRunEmphasis [NUMERICAL]
# 	918 : GrayLevelVariance [NUMERICAL]
# 	914 : RunLengthNonUniformityNormalized [NUMERICAL]
# 	779 : RunVariance [NUMERICAL]
# 	710 : RunLengthNonUniformity [NUMERICAL]
# 	645 : LongRunEmphasis [NUMERICAL]
# 	639 : RunPercentage [NUMERICAL]
#
# Condition type in nodes:
# 	345243 : HigherCondition
# Condition type in nodes with depth <= 0:
# 	300 : HigherCondition
# Condition type in nodes with depth <= 1:
# 	900 : HigherCondition
# Condition type in nodes with depth <= 2:
# 	2100 : HigherCondition
# Condition type in nodes with depth <= 3:
# 	4493 : HigherCondition
# Condition type in nodes with depth <= 5:
# 	16979 : HigherCondition
# Node format: NOT_SET
#
# Training OOB:
# 	trees: 1, Out-of-bag evaluation: accuracy:0.822331 logloss:6.40384
# 	trees: 11, Out-of-bag evaluation: accuracy:0.840356 logloss:2.50659
# 	trees: 21, Out-of-bag evaluation: accuracy:0.854462 logloss:1.52834
# 	trees: 31, Out-of-bag evaluation: accuracy:0.85582 logloss:1.22046
# 	trees: 41, Out-of-bag evaluation: accuracy:0.8586 logloss:1.07463
# 	trees: 51, Out-of-bag evaluation: accuracy:0.860113 logloss:0.955247
# 	trees: 61, Out-of-bag evaluation: accuracy:0.860773 logloss:0.838385
# 	trees: 71, Out-of-bag evaluation: accuracy:0.862205 logloss:0.755005
# 	trees: 81, Out-of-bag evaluation: accuracy:0.862204 logloss:0.713239
# 	trees: 91, Out-of-bag evaluation: accuracy:0.863255 logloss:0.687269
# 	trees: 101, Out-of-bag evaluation: accuracy:0.862096 logloss:0.672245
# 	trees: 111, Out-of-bag evaluation: accuracy:0.862733 logloss:0.648975
# 	trees: 121, Out-of-bag evaluation: accuracy:0.862232 logloss:0.621436
# 	trees: 131, Out-of-bag evaluation: accuracy:0.862877 logloss:0.606415
# 	trees: 141, Out-of-bag evaluation: accuracy:0.861894 logloss:0.592312
# 	trees: 151, Out-of-bag evaluation: accuracy:0.862898 logloss:0.580146
# 	trees: 161, Out-of-bag evaluation: accuracy:0.861839 logloss:0.57443
# 	trees: 171, Out-of-bag evaluation: accuracy:0.862449 logloss:0.565328
# 	trees: 181, Out-of-bag evaluation: accuracy:0.862877 logloss:0.554315
# 	trees: 191, Out-of-bag evaluation: accuracy:0.863502 logloss:0.550713
# 	trees: 201, Out-of-bag evaluation: accuracy:0.86323 logloss:0.542246
# 	trees: 211, Out-of-bag evaluation: accuracy:0.862931 logloss:0.528042
# 	trees: 221, Out-of-bag evaluation: accuracy:0.863475 logloss:0.514336
# 	trees: 231, Out-of-bag evaluation: accuracy:0.862775 logloss:0.50812
# 	trees: 241, Out-of-bag evaluation: accuracy:0.863481 logloss:0.499139
# 	trees: 251, Out-of-bag evaluation: accuracy:0.863366 logloss:0.490933
# 	trees: 261, Out-of-bag evaluation: accuracy:0.863263 logloss:0.487932
# 	trees: 271, Out-of-bag evaluation: accuracy:0.863827 logloss:0.485205
# 	trees: 281, Out-of-bag evaluation: accuracy:0.863663 logloss:0.47628
# 	trees: 291, Out-of-bag evaluation: accuracy:0.863168 logloss:0.475763
# 	trees: 300, Out-of-bag evaluation: accuracy:0.862714 logloss:0.470428

# %%
# Model features
model.make_inspector().features()
# Out:
# ["GrayLevelNonUniformity" (1; #0),
#  "GrayLevelNonUniformityNormalized" (1; #1),
#  "GrayLevelVariance" (1; #2),
#  "HighGrayLevelRunEmphasis" (1; #3),
#  "LongRunEmphasis" (1; #4),
#  "LongRunHighGrayLevelEmphasis" (1; #5),
#  "LongRunLowGrayLevelEmphasis" (1; #6),
#  "LowGrayLevelRunEmphasis" (1; #7),
#  "RunEntropy" (1; #8),
#  "RunLengthNonUniformity" (1; #9),
#  "RunLengthNonUniformityNormalized" (1; #10),
#  "RunPercentage" (1; #11),
#  "RunVariance" (1; #12),
#  "ShortRunEmphasis" (1; #13),
#  "ShortRunHighGrayLevelEmphasis" (1; #14),
#  "ShortRunLowGrayLevelEmphasis" (1; #15)]

# %%
# Feature importance
model.make_inspector().variable_importances()
# Out:
# {'INV_MEAN_MIN_DEPTH': [("LongRunHighGrayLevelEmphasis" (1; #5),
#    0.1995428568096138),
#   ("HighGrayLevelRunEmphasis" (1; #3), 0.1484976283007673),
#   ("ShortRunHighGrayLevelEmphasis" (1; #14), 0.13528244711743934),
#   ("LowGrayLevelRunEmphasis" (1; #7), 0.11904080579793773),
#   ("GrayLevelNonUniformity" (1; #0), 0.1170359105257895),
#   ("LongRunLowGrayLevelEmphasis" (1; #6), 0.11291543662933108),
#   ("RunEntropy" (1; #8), 0.11130046487417339),
#   ("ShortRunLowGrayLevelEmphasis" (1; #15), 0.10872524195216769),
#   ("RunLengthNonUniformityNormalized" (1; #10), 0.10852658870855457),
#   ("ShortRunEmphasis" (1; #13), 0.10651236091199949),
#   ("GrayLevelNonUniformityNormalized" (1; #1), 0.10080123367558229),
#   ("GrayLevelVariance" (1; #2), 0.09296159295338313),
#   ("RunVariance" (1; #12), 0.09200610568636344),
#   ("RunLengthNonUniformity" (1; #9), 0.09190371253615778),
#   ("LongRunEmphasis" (1; #4), 0.08951383583599797),
#   ("RunPercentage" (1; #11), 0.0878447612713773)],
#  'NUM_AS_ROOT': [("LongRunHighGrayLevelEmphasis" (1; #5), 97.0),
#   ("HighGrayLevelRunEmphasis" (1; #3), 68.0),
#   ("ShortRunHighGrayLevelEmphasis" (1; #14), 42.0),
#   ("LowGrayLevelRunEmphasis" (1; #7), 32.0),
#   ("LongRunLowGrayLevelEmphasis" (1; #6), 21.0),
#   ("ShortRunLowGrayLevelEmphasis" (1; #15), 19.0),
#   ("GrayLevelNonUniformity" (1; #0), 8.0),
#   ("GrayLevelNonUniformityNormalized" (1; #1), 8.0),
#   ("RunEntropy" (1; #8), 2.0),
#   ("RunLengthNonUniformity" (1; #9), 1.0),
#   ("RunVariance" (1; #12), 1.0),
#   ("ShortRunEmphasis" (1; #13), 1.0)],
#  'SUM_SCORE': [("LongRunHighGrayLevelEmphasis" (1; #5), 2484748.9559912775),
#   ("HighGrayLevelRunEmphasis" (1; #3), 1680344.933443487),
#   ("ShortRunHighGrayLevelEmphasis" (1; #14), 1314700.0440701258),
#   ("LowGrayLevelRunEmphasis" (1; #7), 1087347.7687431776),
#   ("GrayLevelNonUniformity" (1; #0), 1018207.4915746998),
#   ("RunEntropy" (1; #8), 942592.3279324322),
#   ("LongRunLowGrayLevelEmphasis" (1; #6), 924075.5302589013),
#   ("ShortRunLowGrayLevelEmphasis" (1; #15), 846490.153894152),
#   ("RunLengthNonUniformityNormalized" (1; #10), 639435.8238726103),
#   ("ShortRunEmphasis" (1; #13), 622959.1898000743),
#   ("GrayLevelNonUniformityNormalized" (1; #1), 619615.847573177),
#   ("GrayLevelVariance" (1; #2), 541294.3160570232),
#   ("RunVariance" (1; #12), 460530.90252172074),
#   ("LongRunEmphasis" (1; #4), 414153.08055707556),
#   ("RunLengthNonUniformity" (1; #9), 409983.95155756385),
#   ("RunPercentage" (1; #11), 370826.5338565416)],
#  'NUM_NODES': [("RunEntropy" (1; #8), 27183.0),
#   ("GrayLevelNonUniformity" (1; #0), 27172.0),
#   ("LongRunHighGrayLevelEmphasis" (1; #5), 26767.0),
#   ("GrayLevelVariance" (1; #2), 25678.0),
#   ("GrayLevelNonUniformityNormalized" (1; #1), 23634.0),
#   ("ShortRunLowGrayLevelEmphasis" (1; #15), 21783.0),
#   ("ShortRunHighGrayLevelEmphasis" (1; #14), 21749.0),
#   ("HighGrayLevelRunEmphasis" (1; #3), 21526.0),
#   ("LongRunLowGrayLevelEmphasis" (1; #6), 21261.0),
#   ("LowGrayLevelRunEmphasis" (1; #7), 20566.0),
#   ("RunVariance" (1; #12), 20142.0),
#   ("ShortRunEmphasis" (1; #13), 18672.0),
#   ("RunLengthNonUniformityNormalized" (1; #10), 18659.0),
#   ("LongRunEmphasis" (1; #4), 17609.0),
#   ("RunLengthNonUniformity" (1; #9), 16775.0),
#   ("RunPercentage" (1; #11), 16067.0)]}

# %%
# Model self evaluation
model.make_inspector().evaluation()
# Out:
# Evaluation(num_examples=78790, accuracy=0.8627143081840191, loss=0.4704279624121158, rmse=None, ndcg=None, aucs=None, auuc=None, qini=None)

# %%
logs = model.make_inspector().training_logs()

plt.figure(figsize=(12, 4))
plt.subplot(1, 2, 1)
plt.plot([log.num_trees for log in logs], [log.evaluation.accuracy for log in logs])
plt.xlabel("Number of trees")
plt.ylabel("Accuracy (out-of-bag)")
plt.subplot(1, 2, 2)
plt.plot([log.num_trees for log in logs], [log.evaluation.loss for log in logs])
plt.xlabel("Number of trees")
plt.ylabel("Logloss (out-of-bag)")
plt.show()

# %% [markdown]
# Calculate the score of our hold-out validation dataset

# %%
predictions = model.predict(val_ds)
y_true      = validation_data["label"]

from sklearn.metrics import roc_auc_score
ROC_AUC = roc_auc_score(y_true, predictions)
print("The ROC AUC score is %.5f" % ROC_AUC )
# Out:
#  1/12 [=>............................] - ETA: 0s
#  4/12 [=========>....................] - ETA: 0s
#  6/12 [==============>...............] - ETA: 0s
#  9/12 [=====================>........] - ETA: 0s
# 12/12 [==============================] - ETA: 0s
# 12/12 [==============================] - 0s 23ms/step
# The ROC AUC score is 0.95507

# %%
# Compute binary classification metrics with sklearn
import numpy as np
from sklearn.metrics import (
    accuracy_score,
    precision_score,
    recall_score,
    f1_score,
    roc_auc_score,
    average_precision_score,
    confusion_matrix,
    classification_report,
    matthews_corrcoef,
    log_loss,
    brier_score_loss,
)

# Get predictions (probabilities or class labels)
preds = model.predict(test_ds)
# If model outputs probabilities, convert to labels by threshold 0.5
if preds.ndim == 2:
    # For TFDF classification, preds may be class probabilities with shape (N, 2)
    if preds.shape[1] == 2:
        pos_probs = preds[:, 1]
    else:
        # If single-probability column (positive class)
        pos_probs = preds[:, -1]
    y_pred = (pos_probs >= 0.5).astype(int)
else:
    # Already class labels
    y_pred = preds.astype(int)
    pos_probs = None

# Ground truth labels (must be 0/1 integers)
y_true = test_data["label"].astype(int).to_numpy()

# Core metrics
metrics = {}
metrics["accuracy"] = accuracy_score(y_true, y_pred)
metrics["precision"] = precision_score(y_true, y_pred, zero_division=0)
metrics["recall"] = recall_score(y_true, y_pred, zero_division=0)
metrics["f1"] = f1_score(y_true, y_pred, zero_division=0)
metrics["mcc"] = matthews_corrcoef(y_true, y_pred)

# Probabilistic metrics (only if we have probabilities)
if pos_probs is not None:
    metrics["roc_auc"] = roc_auc_score(y_true, pos_probs)
    metrics["pr_auc"] = average_precision_score(y_true, pos_probs)
    metrics["log_loss"] = log_loss(y_true, pos_probs, labels=[0,1])
    metrics["brier_score"] = brier_score_loss(y_true, pos_probs)

# Confusion matrix and detailed report
cm = confusion_matrix(y_true, y_pred, labels=[0,1])
report = classification_report(y_true, y_pred, digits=4)

print("Sklearn binary metrics:")
for k, v in metrics.items():
    print(f"{k}: {v:.4f}")
print("\nConfusion matrix:\n", cm)
print("\nClassification report:\n", report)
# Out:
#  1/23 [>.............................] - ETA: 2s
#  3/23 [==>...........................] - ETA: 0s
#  6/23 [======>.......................] - ETA: 0s
#  8/23 [=========>....................] - ETA: 0s
# 10/23 [============>.................] - ETA: 0s
# 12/23 [==============>...............] - ETA: 0s
# 14/23 [=================>............] - ETA: 0s
# 16/23 [===================>..........] - ETA: 0s
# 18/23 [======================>.......] - ETA: 0s
# 20/23 [=========================>....] - ETA: 0s
# 22/23 [===========================>..] - ETA: 0s
# 23/23 [==============================] - 1s 25ms/step
# Sklearn binary metrics:
# accuracy: 0.9491
# precision: 0.6116
# recall: 0.7604
# f1: 0.6779
# mcc: 0.6552
# roc_auc: 0.9554
# pr_auc: 0.7817
# log_loss: 0.1414
# brier_score: 0.0392
#
# Confusion matrix:
#  [[20160   766]
#  [  380  1206]]
#
# Classification report:
#                precision    recall  f1-score   support
#
#            0     0.9815    0.9634    0.9724     20926
#            1     0.6116    0.7604    0.6779      1586
#
#     accuracy                         0.9491     22512
#    macro avg     0.7965    0.8619    0.8251     22512
# weighted avg     0.9554    0.9491    0.9516     22512
