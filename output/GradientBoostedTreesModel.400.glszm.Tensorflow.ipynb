# %%
# Import packages and modules
import numpy  as np
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow_decision_forests as tfdf

from sklearn.model_selection import train_test_split
# Out:
# 2026-07-04 09:03:22.201612: I tensorflow/core/util/port.cc:113] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2026-07-04 09:03:22.240029: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2026-07-04 09:03:26.445125: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
# Check the version of TensorFlow Decision Forests
print("Found TensorFlow Decision Forests v" + tfdf.__version__)
# Out:
# Found TensorFlow Decision Forests v1.9.1

# %%
datasetPath = 'dataset/firstorder/kernel5-radius5/dataset.csv'

# %%
# Parameters
datasetPath = "dataset/glszm/kernel5-radius5/400.dataset.csv"

# %%
# train/validation/test = 70/10/20
dataset = pd.read_csv(datasetPath)

train_data, temp_data = train_test_split(dataset, test_size=0.3, random_state=42)
validation_data, test_data = train_test_split(temp_data, test_size=2/3, random_state=42)

# %%
from sklearn.utils.class_weight import compute_class_weight

# tinh class weight tren tap train
classes = np.array([0, 1])
weights = compute_class_weight(class_weight="balanced", classes=classes, y=train_data["label"])
class_weight = {0: weights[0], 1: weights[1]}

# gan sample_weight cho tung dong
train_data["sample_weight"] = train_data["label"].map(class_weight)
validation_data["sample_weight"] = validation_data["label"].map(class_weight)
test_data["sample_weight"] = test_data["label"].map(class_weight)

# Convert the dataset into a TensorFlow dataset.
train_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    train_data, label="label", weight="sample_weight"
)         
val_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    validation_data, label="label", weight="sample_weight"
)
test_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    test_data, label="label", weight="sample_weight"
)
# Out:
# 2026-07-04 09:03:39.114647: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:984] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2026-07-04 09:03:39.116040: W tensorflow/core/common_runtime/gpu/gpu_device.cc:2251] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...

# %%
import keras

# %%
# %%time

# Train a Gradient Boosted Trees model.
model = tfdf.keras.GradientBoostedTreesModel()

# Add evaluation metrics
model.compile(
    metrics=["accuracy"]
)
model.fit(x=train_ds)

# # Train a Gradient Boosted Trees model.
# model = tfdf.keras.GradientBoostedTreesModel(num_trees=1500)
# model.fit(train_ds)
# Out:
# Use /tmp/tmpofeo3tdq as temporary training directory
# Reading training dataset...
# [WARNING 26-07-04 09:03:39.2985 UTC gradient_boosted_trees.cc:1840] "goss_alpha" set but "sampling_method" not equal to "GOSS".
# [WARNING 26-07-04 09:03:39.2986 UTC gradient_boosted_trees.cc:1851] "goss_beta" set but "sampling_method" not equal to "GOSS".
# [WARNING 26-07-04 09:03:39.2986 UTC gradient_boosted_trees.cc:1865] "selective_gradient_boosting_ratio" set but "sampling_method" not equal to "SELGB".
# Training dataset read in 0:00:03.746278. Found 315417 examples.
# Training model...
# Model trained in 0:01:22.435728
# Compiling model...
# [INFO 26-07-04 09:05:05.4872 UTC kernel.cc:1233] Loading model from path /tmp/tmpofeo3tdq/model/ with prefix 8784d8ff2f1545a7
# [INFO 26-07-04 09:05:05.5045 UTC quick_scorer_extended.cc:911] The binary was compiled without AVX2 support, but your CPU supports it. Enable it for faster model inference.
# [INFO 26-07-04 09:05:05.5057 UTC abstract_model.cc:1362] Engine "GradientBoostedTreesQuickScorerExtended" built
# [INFO 26-07-04 09:05:05.5057 UTC kernel.cc:1061] Use fast generic engine
# Model compiled.
# CPU times: user 10min 18s, sys: 4.43 s, total: 10min 22s
# Wall time: 1min 29s

# %%
# Evaluate the model
evaluate = model.evaluate(val_ds, return_dict=True)
print()

for name, value in evaluate.items():
    print(f"{name}: {value:.4f}")
# Out:
# WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
#  1/46 [..............................] - ETA: 2:10 - loss: 0.0000e+00 - accuracy: 0.8760
# 12/46 [======>.......................] - ETA: 0s - loss: 0.0000e+00 - accuracy: 0.8728
# 24/46 [==============>...............] - ETA: 0s - loss: 0.0000e+00 - accuracy: 0.8719
# 36/46 [======================>.......] - ETA: 0s - loss: 0.0000e+00 - accuracy: 0.8724
# 46/46 [==============================] - 3s 4ms/step - loss: 0.0000e+00 - accuracy: 0.8737
# loss: 0.0000
# accuracy: 0.8737

# %%
# Model Summary
model.summary()
# Out:
# Model: "gradient_boosted_trees_model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
# =================================================================
# Total params: 1 (1.00 Byte)
# Trainable params: 0 (0.00 Byte)
# Non-trainable params: 1 (1.00 Byte)
# _________________________________________________________________
# Type: "GRADIENT_BOOSTED_TREES"
# Task: CLASSIFICATION
# Label: "__LABEL"
#
# Input Features (16):
# 	GrayLevelNonUniformity
# 	GrayLevelNonUniformityNormalized
# 	GrayLevelVariance
# 	HighGrayLevelZoneEmphasis
# 	LargeAreaEmphasis
# 	LargeAreaHighGrayLevelEmphasis
# 	LargeAreaLowGrayLevelEmphasis
# 	LowGrayLevelZoneEmphasis
# 	SizeZoneNonUniformity
# 	SizeZoneNonUniformityNormalized
# 	SmallAreaEmphasis
# 	SmallAreaHighGrayLevelEmphasis
# 	SmallAreaLowGrayLevelEmphasis
# 	ZoneEntropy
# 	ZonePercentage
# 	ZoneVariance
#
# Trained with weights
#
# Variable Importance: INV_MEAN_MIN_DEPTH:
#     1.   "LargeAreaHighGrayLevelEmphasis"  0.302210 ################
#     2.           "GrayLevelNonUniformity"  0.224177 ######
#     3.    "LargeAreaLowGrayLevelEmphasis"  0.211995 ####
#     4.                     "ZoneVariance"  0.211070 ####
#     5.        "HighGrayLevelZoneEmphasis"  0.201418 ###
#     6.         "LowGrayLevelZoneEmphasis"  0.200504 ###
#     7.    "SmallAreaLowGrayLevelEmphasis"  0.193760 ##
#     8.  "SizeZoneNonUniformityNormalized"  0.188546 #
#     9.                "GrayLevelVariance"  0.187715 #
#    10.                      "ZoneEntropy"  0.187103 #
#    11.   "SmallAreaHighGrayLevelEmphasis"  0.182967
#    12. "GrayLevelNonUniformityNormalized"  0.181365
#    13.                "SmallAreaEmphasis"  0.180565
#    14.            "SizeZoneNonUniformity"  0.177202
#    15.                "LargeAreaEmphasis"  0.176518
#    16.                   "ZonePercentage"  0.175721
#
# Variable Importance: NUM_AS_ROOT:
#     1.  "LargeAreaHighGrayLevelEmphasis" 121.000000 ################
#     2.          "GrayLevelNonUniformity" 49.000000 ######
#     3.        "LowGrayLevelZoneEmphasis" 24.000000 ###
#     4.   "LargeAreaLowGrayLevelEmphasis" 23.000000 ##
#     5.       "HighGrayLevelZoneEmphasis" 20.000000 ##
#     6. "SizeZoneNonUniformityNormalized" 17.000000 ##
#     7.   "SmallAreaLowGrayLevelEmphasis" 14.000000 #
#     8.                    "ZoneVariance"  9.000000 #
#     9.               "SmallAreaEmphasis"  7.000000
#    10.                     "ZoneEntropy"  5.000000
#    11.               "GrayLevelVariance"  4.000000
#    12.               "LargeAreaEmphasis"  2.000000
#    13.  "SmallAreaHighGrayLevelEmphasis"  2.000000
#    14.           "SizeZoneNonUniformity"  1.000000
#
# Variable Importance: NUM_NODES:
#     1.   "LargeAreaHighGrayLevelEmphasis" 998.000000 ################
#     2.    "LargeAreaLowGrayLevelEmphasis" 861.000000 #############
#     3.           "GrayLevelNonUniformity" 741.000000 ##########
#     4.        "HighGrayLevelZoneEmphasis" 714.000000 ##########
#     5.                     "ZoneVariance" 664.000000 #########
#     6.         "LowGrayLevelZoneEmphasis" 616.000000 ########
#     7.    "SmallAreaLowGrayLevelEmphasis" 535.000000 ######
#     8.                      "ZoneEntropy" 502.000000 #####
#     9.   "SmallAreaHighGrayLevelEmphasis" 469.000000 #####
#    10.                "GrayLevelVariance" 466.000000 #####
#    11. "GrayLevelNonUniformityNormalized" 365.000000 ###
#    12.  "SizeZoneNonUniformityNormalized" 287.000000 #
#    13.            "SizeZoneNonUniformity" 245.000000
#    14.                "SmallAreaEmphasis" 232.000000
#    15.                   "ZonePercentage" 220.000000
#    16.                "LargeAreaEmphasis" 210.000000
#
# Variable Importance: SUM_SCORE:
#     1.        "HighGrayLevelZoneEmphasis" 85993.632432 ################
#     2.           "GrayLevelNonUniformity" 45480.832973 ########
#     3.   "LargeAreaHighGrayLevelEmphasis" 30182.050012 #####
#     4.    "LargeAreaLowGrayLevelEmphasis" 25801.192325 ####
#     5.    "SmallAreaLowGrayLevelEmphasis" 13390.713303 ##
#     6.  "SizeZoneNonUniformityNormalized" 11509.716867 ##
#     7.                      "ZoneEntropy" 11429.623751 ##
#     8.         "LowGrayLevelZoneEmphasis" 10463.406932 #
#     9.                     "ZoneVariance" 7949.187580 #
#    10.   "SmallAreaHighGrayLevelEmphasis" 7550.313980 #
#    11.                "GrayLevelVariance" 3457.834975
#    12. "GrayLevelNonUniformityNormalized" 1944.090246
#    13.            "SizeZoneNonUniformity" 1691.896517
#    14.                "SmallAreaEmphasis" 1345.197548
#    15.                   "ZonePercentage" 1275.499741
#    16.                "LargeAreaEmphasis" 726.903927
#
#
#
# Loss: BINOMIAL_LOG_LIKELIHOOD
# Validation loss value: 0.643179
# Number of trees per iteration: 1
# Node format: NOT_SET
# Number of trees: 298
# Total number of nodes: 16548
#
# Number of nodes by tree:
# Count: 298 Average: 55.5302 StdDev: 7.52986
# Min: 27 Max: 63 Ignored: 0
# ----------------------------------------------
# [ 27, 28)  1   0.34%   0.34%
# [ 28, 30)  0   0.00%   0.34%
# [ 30, 32)  0   0.00%   0.34%
# [ 32, 34)  0   0.00%   0.34%
# [ 34, 36)  1   0.34%   0.67%
# [ 36, 38)  1   0.34%   1.01%
# [ 38, 39)  0   0.00%   1.01%
# [ 39, 41)  5   1.68%   2.68% #
# [ 41, 43)  9   3.02%   5.70% #
# [ 43, 45) 18   6.04%  11.74% ##
# [ 45, 47)  9   3.02%  14.77% #
# [ 47, 49) 16   5.37%  20.13% ##
# [ 49, 51) 18   6.04%  26.17% ##
# [ 51, 52) 10   3.36%  29.53% #
# [ 52, 54) 16   5.37%  34.90% ##
# [ 54, 56) 19   6.38%  41.28% ###
# [ 56, 58) 25   8.39%  49.66% ###
# [ 58, 60) 28   9.40%  59.06% ####
# [ 60, 62) 47  15.77%  74.83% ######
# [ 62, 63] 75  25.17% 100.00% ##########
#
# Depth by leafs:
# Count: 8423 Average: 4.90728 StdDev: 0.387778
# Min: 1 Max: 5 Ignored: 0
# ----------------------------------------------
# [ 1, 2)    1   0.01%   0.01%
# [ 2, 3)   48   0.57%   0.58%
# [ 3, 4)  129   1.53%   2.11%
# [ 4, 5)  375   4.45%   6.57%
# [ 5, 5] 7870  93.43% 100.00% ##########
#
# Number of training obs by leaf:
# Count: 8423 Average: 10039.7 StdDev: 35808.1
# Min: 5 Max: 280218 Ignored: 0
# ----------------------------------------------
# [      5,  14015) 7419  88.08%  88.08% ##########
# [  14015,  28026)  388   4.61%  92.69% #
# [  28026,  42037)  173   2.05%  94.74%
# [  42037,  56047)   85   1.01%  95.75%
# [  56047,  70058)   57   0.68%  96.43%
# [  70058,  84069)   28   0.33%  96.76%
# [  84069,  98079)   24   0.28%  97.04%
# [  98079, 112090)   22   0.26%  97.30%
# [ 112090, 126101)   15   0.18%  97.48%
# [ 126101, 140112)   17   0.20%  97.68%
# [ 140112, 154122)   19   0.23%  97.91%
# [ 154122, 168133)   14   0.17%  98.08%
# [ 168133, 182144)   11   0.13%  98.21%
# [ 182144, 196154)   16   0.19%  98.40%
# [ 196154, 210165)   11   0.13%  98.53%
# [ 210165, 224176)   24   0.28%  98.81%
# [ 224176, 238186)   25   0.30%  99.11%
# [ 238186, 252197)   28   0.33%  99.44%
# [ 252197, 266208)   20   0.24%  99.68%
# [ 266208, 280218]   27   0.32% 100.00%
#
# Attribute in nodes:
# 	998 : LargeAreaHighGrayLevelEmphasis [NUMERICAL]
# 	861 : LargeAreaLowGrayLevelEmphasis [NUMERICAL]
# 	741 : GrayLevelNonUniformity [NUMERICAL]
# 	714 : HighGrayLevelZoneEmphasis [NUMERICAL]
# 	664 : ZoneVariance [NUMERICAL]
# 	616 : LowGrayLevelZoneEmphasis [NUMERICAL]
# 	535 : SmallAreaLowGrayLevelEmphasis [NUMERICAL]
# 	502 : ZoneEntropy [NUMERICAL]
# 	469 : SmallAreaHighGrayLevelEmphasis [NUMERICAL]
# 	466 : GrayLevelVariance [NUMERICAL]
# 	365 : GrayLevelNonUniformityNormalized [NUMERICAL]
# 	287 : SizeZoneNonUniformityNormalized [NUMERICAL]
# 	245 : SizeZoneNonUniformity [NUMERICAL]
# 	232 : SmallAreaEmphasis [NUMERICAL]
# 	220 : ZonePercentage [NUMERICAL]
# 	210 : LargeAreaEmphasis [NUMERICAL]
#
# Attribute in nodes with depth <= 0:
# 	121 : LargeAreaHighGrayLevelEmphasis [NUMERICAL]
# 	49 : GrayLevelNonUniformity [NUMERICAL]
# 	24 : LowGrayLevelZoneEmphasis [NUMERICAL]
# 	23 : LargeAreaLowGrayLevelEmphasis [NUMERICAL]
# 	20 : HighGrayLevelZoneEmphasis [NUMERICAL]
# 	17 : SizeZoneNonUniformityNormalized [NUMERICAL]
# 	14 : SmallAreaLowGrayLevelEmphasis [NUMERICAL]
# 	9 : ZoneVariance [NUMERICAL]
# 	7 : SmallAreaEmphasis [NUMERICAL]
# 	5 : ZoneEntropy [NUMERICAL]
# 	4 : GrayLevelVariance [NUMERICAL]
# 	2 : SmallAreaHighGrayLevelEmphasis [NUMERICAL]
# 	2 : LargeAreaEmphasis [NUMERICAL]
# 	1 : SizeZoneNonUniformity [NUMERICAL]
#
# Attribute in nodes with depth <= 1:
# 	239 : LargeAreaHighGrayLevelEmphasis [NUMERICAL]
# 	126 : GrayLevelNonUniformity [NUMERICAL]
# 	102 : ZoneVariance [NUMERICAL]
# 	86 : LargeAreaLowGrayLevelEmphasis [NUMERICAL]
# 	55 : LowGrayLevelZoneEmphasis [NUMERICAL]
# 	46 : SmallAreaLowGrayLevelEmphasis [NUMERICAL]
# 	42 : HighGrayLevelZoneEmphasis [NUMERICAL]
# 	41 : SizeZoneNonUniformityNormalized [NUMERICAL]
# 	36 : GrayLevelVariance [NUMERICAL]
# 	32 : SmallAreaEmphasis [NUMERICAL]
# 	21 : GrayLevelNonUniformityNormalized [NUMERICAL]
# 	18 : ZoneEntropy [NUMERICAL]
# 	16 : SizeZoneNonUniformity [NUMERICAL]
# 	14 : SmallAreaHighGrayLevelEmphasis [NUMERICAL]
# 	14 : LargeAreaEmphasis [NUMERICAL]
# 	5 : ZonePercentage [NUMERICAL]
#
# Attribute in nodes with depth <= 2:
# 	374 : LargeAreaHighGrayLevelEmphasis [NUMERICAL]
# 	201 : ZoneVariance [NUMERICAL]
# 	192 : LargeAreaLowGrayLevelEmphasis [NUMERICAL]
# 	191 : GrayLevelNonUniformity [NUMERICAL]
# 	169 : HighGrayLevelZoneEmphasis [NUMERICAL]
# 	155 : LowGrayLevelZoneEmphasis [NUMERICAL]
# 	115 : ZoneEntropy [NUMERICAL]
# 	109 : SmallAreaLowGrayLevelEmphasis [NUMERICAL]
# 	104 : GrayLevelVariance [NUMERICAL]
# 	77 : SmallAreaHighGrayLevelEmphasis [NUMERICAL]
# 	75 : SizeZoneNonUniformityNormalized [NUMERICAL]
# 	75 : GrayLevelNonUniformityNormalized [NUMERICAL]
# 	65 : SmallAreaEmphasis [NUMERICAL]
# 	50 : SizeZoneNonUniformity [NUMERICAL]
# 	43 : LargeAreaEmphasis [NUMERICAL]
# 	40 : ZonePercentage [NUMERICAL]
#
# Attribute in nodes with depth <= 3:
# 	600 : LargeAreaHighGrayLevelEmphasis [NUMERICAL]
# 	409 : LargeAreaLowGrayLevelEmphasis [NUMERICAL]
# 	392 : GrayLevelNonUniformity [NUMERICAL]
# 	372 : ZoneVariance [NUMERICAL]
# 	359 : HighGrayLevelZoneEmphasis [NUMERICAL]
# 	320 : LowGrayLevelZoneEmphasis [NUMERICAL]
# 	259 : ZoneEntropy [NUMERICAL]
# 	248 : SmallAreaLowGrayLevelEmphasis [NUMERICAL]
# 	241 : GrayLevelVariance [NUMERICAL]
# 	232 : SmallAreaHighGrayLevelEmphasis [NUMERICAL]
# 	177 : GrayLevelNonUniformityNormalized [NUMERICAL]
# 	143 : SizeZoneNonUniformityNormalized [NUMERICAL]
# 	124 : SmallAreaEmphasis [NUMERICAL]
# 	113 : ZonePercentage [NUMERICAL]
# 	107 : SizeZoneNonUniformity [NUMERICAL]
# 	94 : LargeAreaEmphasis [NUMERICAL]
#
# Attribute in nodes with depth <= 5:
# 	998 : LargeAreaHighGrayLevelEmphasis [NUMERICAL]
# 	861 : LargeAreaLowGrayLevelEmphasis [NUMERICAL]
# 	741 : GrayLevelNonUniformity [NUMERICAL]
# 	714 : HighGrayLevelZoneEmphasis [NUMERICAL]
# 	664 : ZoneVariance [NUMERICAL]
# 	616 : LowGrayLevelZoneEmphasis [NUMERICAL]
# 	535 : SmallAreaLowGrayLevelEmphasis [NUMERICAL]
# 	502 : ZoneEntropy [NUMERICAL]
# 	469 : SmallAreaHighGrayLevelEmphasis [NUMERICAL]
# 	466 : GrayLevelVariance [NUMERICAL]
# 	365 : GrayLevelNonUniformityNormalized [NUMERICAL]
# 	287 : SizeZoneNonUniformityNormalized [NUMERICAL]
# 	245 : SizeZoneNonUniformity [NUMERICAL]
# 	232 : SmallAreaEmphasis [NUMERICAL]
# 	220 : ZonePercentage [NUMERICAL]
# 	210 : LargeAreaEmphasis [NUMERICAL]
#
# Condition type in nodes:
# 	8125 : HigherCondition
# Condition type in nodes with depth <= 0:
# 	298 : HigherCondition
# Condition type in nodes with depth <= 1:
# 	893 : HigherCondition
# Condition type in nodes with depth <= 2:
# 	2035 : HigherCondition
# Condition type in nodes with depth <= 3:
# 	4190 : HigherCondition
# Condition type in nodes with depth <= 5:
# 	8125 : HigherCondition
#
# Training logs:
# Number of iteration to final model: 298
# 	Iter:1 train-loss:1.297147 valid-loss:1.299516  train-accuracy:0.813873 valid-accuracy:0.803702
# 	Iter:2 train-loss:1.224113 valid-loss:1.228961  train-accuracy:0.815274 valid-accuracy:0.804253
# 	Iter:3 train-loss:1.160508 valid-loss:1.167583  train-accuracy:0.821881 valid-accuracy:0.811042
# 	Iter:4 train-loss:1.107693 valid-loss:1.116877  train-accuracy:0.821120 valid-accuracy:0.808686
# 	Iter:5 train-loss:1.061761 valid-loss:1.073390  train-accuracy:0.823439 valid-accuracy:0.810955
# 	Iter:6 train-loss:1.022458 valid-loss:1.035410  train-accuracy:0.826145 valid-accuracy:0.813910
# 	Iter:16 train-loss:0.793237 valid-loss:0.820979  train-accuracy:0.848223 valid-accuracy:0.836827
# 	Iter:26 train-loss:0.706814 valid-loss:0.744877  train-accuracy:0.857744 valid-accuracy:0.843191
# 	Iter:36 train-loss:0.668593 valid-loss:0.713243  train-accuracy:0.862412 valid-accuracy:0.845712
# 	Iter:46 train-loss:0.645094 valid-loss:0.696635  train-accuracy:0.867246 valid-accuracy:0.848546
# 	Iter:56 train-loss:0.628502 valid-loss:0.686113  train-accuracy:0.869725 valid-accuracy:0.849983
# 	Iter:66 train-loss:0.616615 valid-loss:0.678937  train-accuracy:0.871769 valid-accuracy:0.851380
# 	Iter:76 train-loss:0.605475 valid-loss:0.672974  train-accuracy:0.874404 valid-accuracy:0.852225
# 	Iter:86 train-loss:0.598142 valid-loss:0.669798  train-accuracy:0.875701 valid-accuracy:0.852967
# 	Iter:96 train-loss:0.590285 valid-loss:0.665316  train-accuracy:0.877770 valid-accuracy:0.852238
# 	Iter:106 train-loss:0.582593 valid-loss:0.662110  train-accuracy:0.879600 valid-accuracy:0.853566
# 	Iter:116 train-loss:0.578033 valid-loss:0.660803  train-accuracy:0.880524 valid-accuracy:0.854189
# 	Iter:126 train-loss:0.572438 valid-loss:0.658777  train-accuracy:0.881713 valid-accuracy:0.854565
# 	Iter:136 train-loss:0.567358 valid-loss:0.657409  train-accuracy:0.883066 valid-accuracy:0.854752
# 	Iter:146 train-loss:0.561984 valid-loss:0.656417  train-accuracy:0.884176 valid-accuracy:0.855559
# 	Iter:156 train-loss:0.556975 valid-loss:0.655560  train-accuracy:0.885108 valid-accuracy:0.855595
# 	Iter:166 train-loss:0.552151 valid-loss:0.654579  train-accuracy:0.886260 valid-accuracy:0.856253
# 	Iter:176 train-loss:0.548480 valid-loss:0.653400  train-accuracy:0.887208 valid-accuracy:0.856623
# 	Iter:186 train-loss:0.544478 valid-loss:0.652267  train-accuracy:0.888652 valid-accuracy:0.857045
# 	Iter:196 train-loss:0.540176 valid-loss:0.651188  train-accuracy:0.889761 valid-accuracy:0.857517
# 	Iter:206 train-loss:0.536461 valid-loss:0.650422  train-accuracy:0.890515 valid-accuracy:0.857804
# 	Iter:216 train-loss:0.532352 valid-loss:0.649028  train-accuracy:0.891824 valid-accuracy:0.857974
# 	Iter:226 train-loss:0.528212 valid-loss:0.647950  train-accuracy:0.892598 valid-accuracy:0.858147
# 	Iter:236 train-loss:0.524448 valid-loss:0.647204  train-accuracy:0.893450 valid-accuracy:0.857867
# 	Iter:246 train-loss:0.519473 valid-loss:0.645541  train-accuracy:0.894753 valid-accuracy:0.858805
# 	Iter:256 train-loss:0.516014 valid-loss:0.644958  train-accuracy:0.895581 valid-accuracy:0.858826
# 	Iter:266 train-loss:0.512592 valid-loss:0.644778  train-accuracy:0.896766 valid-accuracy:0.858611
# 	Iter:276 train-loss:0.509866 valid-loss:0.644147  train-accuracy:0.897299 valid-accuracy:0.859683
# 	Iter:286 train-loss:0.507190 valid-loss:0.643774  train-accuracy:0.897980 valid-accuracy:0.859753
# 	Iter:296 train-loss:0.503986 valid-loss:0.643259  train-accuracy:0.898755 valid-accuracy:0.858954

# %%
# Model features
model.make_inspector().features()
# Out:
# ["GrayLevelNonUniformity" (1; #0),
#  "GrayLevelNonUniformityNormalized" (1; #1),
#  "GrayLevelVariance" (1; #2),
#  "HighGrayLevelZoneEmphasis" (1; #3),
#  "LargeAreaEmphasis" (1; #4),
#  "LargeAreaHighGrayLevelEmphasis" (1; #5),
#  "LargeAreaLowGrayLevelEmphasis" (1; #6),
#  "LowGrayLevelZoneEmphasis" (1; #7),
#  "SizeZoneNonUniformity" (1; #8),
#  "SizeZoneNonUniformityNormalized" (1; #9),
#  "SmallAreaEmphasis" (1; #10),
#  "SmallAreaHighGrayLevelEmphasis" (1; #11),
#  "SmallAreaLowGrayLevelEmphasis" (1; #12),
#  "ZoneEntropy" (1; #13),
#  "ZonePercentage" (1; #14),
#  "ZoneVariance" (1; #15)]

# %%
# Feature importance
model.make_inspector().variable_importances()
# Out:
# {'INV_MEAN_MIN_DEPTH': [("LargeAreaHighGrayLevelEmphasis" (1; #5),
#    0.302210496315333),
#   ("GrayLevelNonUniformity" (1; #0), 0.22417662494653276),
#   ("LargeAreaLowGrayLevelEmphasis" (1; #6), 0.21199491312280586),
#   ("ZoneVariance" (1; #15), 0.21107007991535487),
#   ("HighGrayLevelZoneEmphasis" (1; #3), 0.20141781485616292),
#   ("LowGrayLevelZoneEmphasis" (1; #7), 0.200503822066877),
#   ("SmallAreaLowGrayLevelEmphasis" (1; #12), 0.1937598130818889),
#   ("SizeZoneNonUniformityNormalized" (1; #9), 0.1885461077667223),
#   ("GrayLevelVariance" (1; #2), 0.18771472285207777),
#   ("ZoneEntropy" (1; #13), 0.18710260738212317),
#   ("SmallAreaHighGrayLevelEmphasis" (1; #11), 0.18296674999902518),
#   ("GrayLevelNonUniformityNormalized" (1; #1), 0.1813653307211103),
#   ("SmallAreaEmphasis" (1; #10), 0.18056534955094838),
#   ("SizeZoneNonUniformity" (1; #8), 0.17720198282384714),
#   ("LargeAreaEmphasis" (1; #4), 0.1765176047822167),
#   ("ZonePercentage" (1; #14), 0.17572078232140217)],
#  'SUM_SCORE': [("HighGrayLevelZoneEmphasis" (1; #3), 85993.63243204124),
#   ("GrayLevelNonUniformity" (1; #0), 45480.83297255946),
#   ("LargeAreaHighGrayLevelEmphasis" (1; #5), 30182.05001223411),
#   ("LargeAreaLowGrayLevelEmphasis" (1; #6), 25801.192324987052),
#   ("SmallAreaLowGrayLevelEmphasis" (1; #12), 13390.713302750684),
#   ("SizeZoneNonUniformityNormalized" (1; #9), 11509.716867420213),
#   ("ZoneEntropy" (1; #13), 11429.62375083732),
#   ("LowGrayLevelZoneEmphasis" (1; #7), 10463.406931651789),
#   ("ZoneVariance" (1; #15), 7949.187579682203),
#   ("SmallAreaHighGrayLevelEmphasis" (1; #11), 7550.313979530006),
#   ("GrayLevelVariance" (1; #2), 3457.834974945835),
#   ("GrayLevelNonUniformityNormalized" (1; #1), 1944.0902457477684),
#   ("SizeZoneNonUniformity" (1; #8), 1691.8965171356883),
#   ("SmallAreaEmphasis" (1; #10), 1345.1975483047631),
#   ("ZonePercentage" (1; #14), 1275.4997411875818),
#   ("LargeAreaEmphasis" (1; #4), 726.9039266319386)],
#  'NUM_AS_ROOT': [("LargeAreaHighGrayLevelEmphasis" (1; #5), 121.0),
#   ("GrayLevelNonUniformity" (1; #0), 49.0),
#   ("LowGrayLevelZoneEmphasis" (1; #7), 24.0),
#   ("LargeAreaLowGrayLevelEmphasis" (1; #6), 23.0),
#   ("HighGrayLevelZoneEmphasis" (1; #3), 20.0),
#   ("SizeZoneNonUniformityNormalized" (1; #9), 17.0),
#   ("SmallAreaLowGrayLevelEmphasis" (1; #12), 14.0),
#   ("ZoneVariance" (1; #15), 9.0),
#   ("SmallAreaEmphasis" (1; #10), 7.0),
#   ("ZoneEntropy" (1; #13), 5.0),
#   ("GrayLevelVariance" (1; #2), 4.0),
#   ("LargeAreaEmphasis" (1; #4), 2.0),
#   ("SmallAreaHighGrayLevelEmphasis" (1; #11), 2.0),
#   ("SizeZoneNonUniformity" (1; #8), 1.0)],
#  'NUM_NODES': [("LargeAreaHighGrayLevelEmphasis" (1; #5), 998.0),
#   ("LargeAreaLowGrayLevelEmphasis" (1; #6), 861.0),
#   ("GrayLevelNonUniformity" (1; #0), 741.0),
#   ("HighGrayLevelZoneEmphasis" (1; #3), 714.0),
#   ("ZoneVariance" (1; #15), 664.0),
#   ("LowGrayLevelZoneEmphasis" (1; #7), 616.0),
#   ("SmallAreaLowGrayLevelEmphasis" (1; #12), 535.0),
#   ("ZoneEntropy" (1; #13), 502.0),
#   ("SmallAreaHighGrayLevelEmphasis" (1; #11), 469.0),
#   ("GrayLevelVariance" (1; #2), 466.0),
#   ("GrayLevelNonUniformityNormalized" (1; #1), 365.0),
#   ("SizeZoneNonUniformityNormalized" (1; #9), 287.0),
#   ("SizeZoneNonUniformity" (1; #8), 245.0),
#   ("SmallAreaEmphasis" (1; #10), 232.0),
#   ("ZonePercentage" (1; #14), 220.0),
#   ("LargeAreaEmphasis" (1; #4), 210.0)]}

# %%
# Model self evaluation
model.make_inspector().evaluation()
# Out:
# Evaluation(num_examples=None, accuracy=0.859004557132721, loss=0.6431788206100464, rmse=None, ndcg=None, aucs=None, auuc=None, qini=None)

# %%
logs = model.make_inspector().training_logs()

plt.figure(figsize=(12, 4))
plt.subplot(1, 2, 1)
plt.plot([log.num_trees for log in logs], [log.evaluation.accuracy for log in logs])
plt.xlabel("Number of trees")
plt.ylabel("Accuracy (out-of-bag)")
plt.subplot(1, 2, 2)
plt.plot([log.num_trees for log in logs], [log.evaluation.loss for log in logs])
plt.xlabel("Number of trees")
plt.ylabel("Logloss (out-of-bag)")
plt.show()

# %% [markdown]
# Calculate the score of our hold-out validation dataset

# %%
predictions = model.predict(val_ds)
y_true      = validation_data["label"]

from sklearn.metrics import roc_auc_score
ROC_AUC = roc_auc_score(y_true, predictions)
print("The ROC AUC score is %.5f" % ROC_AUC )
# Out:
#  1/46 [..............................] - ETA: 2s
# 14/46 [========>.....................] - ETA: 0s
# 28/46 [=================>............] - ETA: 0s
# 42/46 [==========================>...] - ETA: 0s
# 46/46 [==============================] - 0s 4ms/step
# The ROC AUC score is 0.93625

# %%
# Compute binary classification metrics with sklearn
import numpy as np
from sklearn.metrics import (
    accuracy_score,
    precision_score,
    recall_score,
    f1_score,
    roc_auc_score,
    average_precision_score,
    confusion_matrix,
    classification_report,
    matthews_corrcoef,
    log_loss,
    brier_score_loss,
)

# Get predictions (probabilities or class labels)
preds = model.predict(test_ds)
# If model outputs probabilities, convert to labels by threshold 0.5
if preds.ndim == 2:
    # For TFDF classification, preds may be class probabilities with shape (N, 2)
    if preds.shape[1] == 2:
        pos_probs = preds[:, 1]
    else:
        # If single-probability column (positive class)
        pos_probs = preds[:, -1]
    y_pred = (pos_probs >= 0.5).astype(int)
else:
    # Already class labels
    y_pred = preds.astype(int)
    pos_probs = None

# Ground truth labels (must be 0/1 integers)
y_true = test_data["label"].astype(int).to_numpy()

# Core metrics
metrics = {}
metrics["accuracy"] = accuracy_score(y_true, y_pred)
metrics["precision"] = precision_score(y_true, y_pred, zero_division=0)
metrics["recall"] = recall_score(y_true, y_pred, zero_division=0)
metrics["f1"] = f1_score(y_true, y_pred, zero_division=0)
metrics["mcc"] = matthews_corrcoef(y_true, y_pred)

# Probabilistic metrics (only if we have probabilities)
if pos_probs is not None:
    metrics["roc_auc"] = roc_auc_score(y_true, pos_probs)
    metrics["pr_auc"] = average_precision_score(y_true, pos_probs)
    metrics["log_loss"] = log_loss(y_true, pos_probs, labels=[0,1])
    metrics["brier_score"] = brier_score_loss(y_true, pos_probs)

# Confusion matrix and detailed report
cm = confusion_matrix(y_true, y_pred, labels=[0,1])
report = classification_report(y_true, y_pred, digits=4)

print("Sklearn binary metrics:")
for k, v in metrics.items():
    print(f"{k}: {v:.4f}")
print("\nConfusion matrix:\n", cm)
print("\nClassification report:\n", report)
# Out:
#  1/91 [..............................] - ETA: 5s
# 13/91 [===>..........................] - ETA: 0s
# 25/91 [=======>......................] - ETA: 0s
# 37/91 [===========>..................] - ETA: 0s
# 49/91 [===============>..............] - ETA: 0s
# 62/91 [===================>..........] - ETA: 0s
# 74/91 [=======================>......] - ETA: 0s
# 87/91 [===========================>..] - ETA: 0s
# 91/91 [==============================] - 0s 4ms/step
# Sklearn binary metrics:
# accuracy: 0.8776
# precision: 0.3245
# recall: 0.8453
# f1: 0.4690
# mcc: 0.4761
# roc_auc: 0.9400
# pr_auc: 0.6468
# log_loss: 0.2808
# brier_score: 0.0872
#
# Confusion matrix:
#  [[74221 10138]
#  [  891  4870]]
#
# Classification report:
#                precision    recall  f1-score   support
#
#            0     0.9881    0.8798    0.9308     84359
#            1     0.3245    0.8453    0.4690      5761
#
#     accuracy                         0.8776     90120
#    macro avg     0.6563    0.8626    0.6999     90120
# weighted avg     0.9457    0.8776    0.9013     90120
