# %%
# Import packages and modules
import numpy  as np
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow_decision_forests as tfdf

from sklearn.model_selection import train_test_split
# Out:
# 2026-07-04 08:58:17.500512: I tensorflow/core/util/port.cc:113] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2026-07-04 08:58:17.540450: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2026-07-04 08:58:21.819064: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
# Check the version of TensorFlow Decision Forests
print("Found TensorFlow Decision Forests v" + tfdf.__version__)
# Out:
# Found TensorFlow Decision Forests v1.9.1

# %%
datasetPath = 'dataset/firstorder/kernel5-radius5/dataset.csv'

# %%
# Parameters
datasetPath = "dataset/glrlm/kernel5-radius5/500.dataset.csv"

# %%
# train/validation/test = 70/10/20
dataset = pd.read_csv(datasetPath)

train_data, temp_data = train_test_split(dataset, test_size=0.3, random_state=42)
validation_data, test_data = train_test_split(temp_data, test_size=2/3, random_state=42)

# %%
from sklearn.utils.class_weight import compute_class_weight

# tinh class weight tren tap train
classes = np.array([0, 1])
weights = compute_class_weight(class_weight="balanced", classes=classes, y=train_data["label"])
class_weight = {0: weights[0], 1: weights[1]}

# gan sample_weight cho tung dong
train_data["sample_weight"] = train_data["label"].map(class_weight)
validation_data["sample_weight"] = validation_data["label"].map(class_weight)
test_data["sample_weight"] = test_data["label"].map(class_weight)

# Convert the dataset into a TensorFlow dataset.
train_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    train_data, label="label", weight="sample_weight"
)         
val_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    validation_data, label="label", weight="sample_weight"
)
test_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    test_data, label="label", weight="sample_weight"
)
# Out:
# 2026-07-04 08:58:36.385284: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:984] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2026-07-04 08:58:36.386650: W tensorflow/core/common_runtime/gpu/gpu_device.cc:2251] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...

# %%
import keras

# %%
# %%time

# Train a Random Forest model.
model = tfdf.keras.RandomForestModel()

# Add evaluation metrics
model.compile(
    metrics=["accuracy"]
)
model.fit(x=train_ds)

# # Train a Gradient Boosted Trees model.
# model = tfdf.keras.GradientBoostedTreesModel(num_trees=1500)
# model.fit(train_ds)
# Out:
# Use /tmp/tmpqltbk85t as temporary training directory
# Reading training dataset...
# Training dataset read in 0:00:04.051792. Found 395218 examples.
# Training model...
# [INFO 26-07-04 08:59:26.9621 UTC kernel.cc:1233] Loading model from path /tmp/tmpqltbk85t/model/ with prefix 5196548844ce4255
# [INFO 26-07-04 08:59:29.5632 UTC decision_forest.cc:734] Model loaded with 300 root(s), 2045056 node(s), and 16 input feature(s).
# [INFO 26-07-04 08:59:29.5633 UTC abstract_model.cc:1362] Engine "RandomForestOptPred" built
# [INFO 26-07-04 08:59:29.5633 UTC kernel.cc:1061] Use fast generic engine
# Model trained in 0:00:49.267270
# Compiling model...
# Model compiled.
# CPU times: user 9min 4s, sys: 2.91 s, total: 9min 7s
# Wall time: 58.2 s

# %%
# Evaluate the model
evaluate = model.evaluate(val_ds, return_dict=True)
print()

for name, value in evaluate.items():
    print(f"{name}: {value:.4f}")
# Out:
# WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
#  1/57 [..............................] - ETA: 2:38 - loss: 0.0000e+00 - accuracy: 0.9040
#  3/57 [>.............................] - ETA: 2s - loss: 0.0000e+00 - accuracy: 0.9103
#  5/57 [=>............................] - ETA: 2s - loss: 0.0000e+00 - accuracy: 0.9126
#  7/57 [==>...........................] - ETA: 1s - loss: 0.0000e+00 - accuracy: 0.9139
#  9/57 [===>..........................] - ETA: 1s - loss: 0.0000e+00 - accuracy: 0.9130
# 11/57 [====>.........................] - ETA: 1s - loss: 0.0000e+00 - accuracy: 0.9135
# 13/57 [=====>........................] - ETA: 1s - loss: 0.0000e+00 - accuracy: 0.9136
# 15/57 [======>.......................] - ETA: 1s - loss: 0.0000e+00 - accuracy: 0.9131
# 17/57 [=======>......................] - ETA: 1s - loss: 0.0000e+00 - accuracy: 0.9122
# 19/57 [=========>....................] - ETA: 1s - loss: 0.0000e+00 - accuracy: 0.9119
# 21/57 [==========>...................] - ETA: 1s - loss: 0.0000e+00 - accuracy: 0.9127
# 23/57 [===========>..................] - ETA: 1s - loss: 0.0000e+00 - accuracy: 0.9134
# 25/57 [============>.................] - ETA: 1s - loss: 0.0000e+00 - accuracy: 0.9131
# 27/57 [=============>................] - ETA: 1s - loss: 0.0000e+00 - accuracy: 0.9130
# 29/57 [==============>...............] - ETA: 1s - loss: 0.0000e+00 - accuracy: 0.9129
# 31/57 [===============>..............] - ETA: 1s - loss: 0.0000e+00 - accuracy: 0.9129
# 33/57 [================>.............] - ETA: 0s - loss: 0.0000e+00 - accuracy: 0.9135
# 35/57 [=================>............] - ETA: 0s - loss: 0.0000e+00 - accuracy: 0.9134
# 37/57 [==================>...........] - ETA: 0s - loss: 0.0000e+00 - accuracy: 0.9132
# 39/57 [===================>..........] - ETA: 0s - loss: 0.0000e+00 - accuracy: 0.9134
# 41/57 [====================>.........] - ETA: 0s - loss: 0.0000e+00 - accuracy: 0.9131
# 43/57 [=====================>........] - ETA: 0s - loss: 0.0000e+00 - accuracy: 0.9128
# 45/57 [======================>.......] - ETA: 0s - loss: 0.0000e+00 - accuracy: 0.9127
# 47/57 [=======================>......] - ETA: 0s - loss: 0.0000e+00 - accuracy: 0.9127
# 49/57 [========================>.....] - ETA: 0s - loss: 0.0000e+00 - accuracy: 0.9125
# 51/57 [=========================>....] - ETA: 0s - loss: 0.0000e+00 - accuracy: 0.9125
# 53/57 [==========================>...] - ETA: 0s - loss: 0.0000e+00 - accuracy: 0.9125
# 55/57 [===========================>..] - ETA: 0s - loss: 0.0000e+00 - accuracy: 0.9126
# 57/57 [==============================] - ETA: 0s - loss: 0.0000e+00 - accuracy: 0.9129
# 57/57 [==============================] - 5s 39ms/step - loss: 0.0000e+00 - accuracy: 0.9129
# loss: 0.0000
# accuracy: 0.9129

# %%
# Model Summary
model.summary()
# Out:
# Model: "random_forest_model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
# =================================================================
# Total params: 1 (1.00 Byte)
# Trainable params: 0 (0.00 Byte)
# Non-trainable params: 1 (1.00 Byte)
# _________________________________________________________________
# Type: "RANDOM_FOREST"
# Task: CLASSIFICATION
# Label: "__LABEL"
#
# Input Features (16):
# 	GrayLevelNonUniformity
# 	GrayLevelNonUniformityNormalized
# 	GrayLevelVariance
# 	HighGrayLevelRunEmphasis
# 	LongRunEmphasis
# 	LongRunHighGrayLevelEmphasis
# 	LongRunLowGrayLevelEmphasis
# 	LowGrayLevelRunEmphasis
# 	RunEntropy
# 	RunLengthNonUniformity
# 	RunLengthNonUniformityNormalized
# 	RunPercentage
# 	RunVariance
# 	ShortRunEmphasis
# 	ShortRunHighGrayLevelEmphasis
# 	ShortRunLowGrayLevelEmphasis
#
# Trained with weights
#
# Variable Importance: INV_MEAN_MIN_DEPTH:
#     1.     "LongRunHighGrayLevelEmphasis"  0.177936 ################
#     2.          "LowGrayLevelRunEmphasis"  0.137046 #########
#     3.     "ShortRunLowGrayLevelEmphasis"  0.136064 #########
#     4.         "HighGrayLevelRunEmphasis"  0.134370 ########
#     5.    "ShortRunHighGrayLevelEmphasis"  0.118908 ######
#     6.                       "RunEntropy"  0.116671 #####
#     7.      "LongRunLowGrayLevelEmphasis"  0.109823 ####
#     8.           "GrayLevelNonUniformity"  0.107404 ####
#     9.                      "RunVariance"  0.093060 #
#    10. "GrayLevelNonUniformityNormalized"  0.090052 #
#    11.                  "LongRunEmphasis"  0.088455 #
#    12.                 "ShortRunEmphasis"  0.087321
#    13.                "GrayLevelVariance"  0.085607
#    14. "RunLengthNonUniformityNormalized"  0.085440
#    15.                    "RunPercentage"  0.084761
#    16.           "RunLengthNonUniformity"  0.081762
#
# Variable Importance: NUM_AS_ROOT:
#     1.          "LowGrayLevelRunEmphasis" 80.000000 ################
#     2.     "ShortRunLowGrayLevelEmphasis" 66.000000 #############
#     3.      "LongRunLowGrayLevelEmphasis" 57.000000 ###########
#     4.         "HighGrayLevelRunEmphasis" 32.000000 ######
#     5.     "LongRunHighGrayLevelEmphasis" 29.000000 #####
#     6.                       "RunEntropy" 14.000000 ##
#     7.    "ShortRunHighGrayLevelEmphasis" 10.000000 #
#     8.           "GrayLevelNonUniformity"  9.000000 #
#     9. "GrayLevelNonUniformityNormalized"  2.000000
#    10.                      "RunVariance"  1.000000
#
# Variable Importance: NUM_NODES:
#     1.                       "RunEntropy" 82120.000000 ################
#     2.           "GrayLevelNonUniformity" 79841.000000 ##############
#     3.     "LongRunHighGrayLevelEmphasis" 78201.000000 ##############
#     4.                "GrayLevelVariance" 77068.000000 #############
#     5. "GrayLevelNonUniformityNormalized" 70336.000000 ##########
#     6.     "ShortRunLowGrayLevelEmphasis" 65777.000000 ########
#     7.    "ShortRunHighGrayLevelEmphasis" 64028.000000 #######
#     8.      "LongRunLowGrayLevelEmphasis" 62831.000000 #######
#     9.                      "RunVariance" 61808.000000 ######
#    10.         "HighGrayLevelRunEmphasis" 60888.000000 ######
#    11.          "LowGrayLevelRunEmphasis" 59673.000000 #####
#    12. "RunLengthNonUniformityNormalized" 55035.000000 ###
#    13.                 "ShortRunEmphasis" 53786.000000 ##
#    14.                  "LongRunEmphasis" 53297.000000 ##
#    15.           "RunLengthNonUniformity" 50155.000000 #
#    16.                    "RunPercentage" 47534.000000
#
# Variable Importance: SUM_SCORE:
#     1.     "LongRunHighGrayLevelEmphasis" 8471447.167032 ################
#     2.     "ShortRunLowGrayLevelEmphasis" 6214780.932661 ##########
#     3.          "LowGrayLevelRunEmphasis" 6089688.286030 ##########
#     4.         "HighGrayLevelRunEmphasis" 5669665.421984 #########
#     5.                       "RunEntropy" 4735045.858272 #######
#     6.    "ShortRunHighGrayLevelEmphasis" 4431688.894976 ######
#     7.      "LongRunLowGrayLevelEmphasis" 4388235.133521 ######
#     8.           "GrayLevelNonUniformity" 4299445.259878 ######
#     9. "GrayLevelNonUniformityNormalized" 2546818.540405 ##
#    10.                      "RunVariance" 2531552.230908 ##
#    11.                "GrayLevelVariance" 2296382.686652 #
#    12.                  "LongRunEmphasis" 2118007.531333 #
#    13.                 "ShortRunEmphasis" 1961223.356209
#    14. "RunLengthNonUniformityNormalized" 1891184.012233
#    15.                    "RunPercentage" 1738591.326639
#    16.           "RunLengthNonUniformity" 1545127.269859
#
#
#
# Winner takes all: true
# Out-of-bag evaluation: accuracy:0.852146 logloss:0.498875
# Number of trees: 300
# Total number of nodes: 2045056
#
# Number of nodes by tree:
# Count: 300 Average: 6816.85 StdDev: 416.714
# Min: 5227 Max: 7877 Ignored: 0
# ----------------------------------------------
# [ 5227, 5359)  2   0.67%   0.67%
# [ 5359, 5492)  2   0.67%   1.33%
# [ 5492, 5624)  0   0.00%   1.33%
# [ 5624, 5757)  0   0.00%   1.33%
# [ 5757, 5889)  2   0.67%   2.00%
# [ 5889, 6022)  9   3.00%   5.00% ##
# [ 6022, 6154)  3   1.00%   6.00% #
# [ 6154, 6287) 14   4.67%  10.67% ###
# [ 6287, 6419) 13   4.33%  15.00% ###
# [ 6419, 6552) 31  10.33%  25.33% ########
# [ 6552, 6685) 31  10.33%  35.67% ########
# [ 6685, 6817) 27   9.00%  44.67% #######
# [ 6817, 6950) 39  13.00%  57.67% ##########
# [ 6950, 7082) 41  13.67%  71.33% ##########
# [ 7082, 7215) 41  13.67%  85.00% ##########
# [ 7215, 7347) 22   7.33%  92.33% #####
# [ 7347, 7480) 16   5.33%  97.67% ####
# [ 7480, 7612)  4   1.33%  99.00% #
# [ 7612, 7745)  2   0.67%  99.67%
# [ 7745, 7877]  1   0.33% 100.00%
#
# Depth by leafs:
# Count: 1.02268e+06 Average: 13.5137 StdDev: 1.8004
# Min: 4 Max: 15 Ignored: 0
# ----------------------------------------------
# [  4,  5)     44   0.00%   0.00%
# [  5,  6)    386   0.04%   0.04%
# [  6,  7)   1535   0.15%   0.19%
# [  7,  8)   4609   0.45%   0.64%
# [  8,  9)  10741   1.05%   1.69%
# [  9, 10)  21882   2.14%   3.83%
# [ 10, 11)  40546   3.96%   7.80% #
# [ 11, 12)  68035   6.65%  14.45% ##
# [ 12, 13) 103760  10.15%  24.60% ##
# [ 13, 14) 144260  14.11%  38.70% ###
# [ 14, 15) 183872  17.98%  56.68% ####
# [ 15, 15] 443008  43.32% 100.00% ##########
#
# Number of training obs by leaf:
# Count: 1.02268e+06 Average: 115.936 StdDev: 527.991
# Min: 5 Max: 27657 Ignored: 0
# ----------------------------------------------
# [     5,  1387) 1.00983e+06  98.74%  98.74% ##########
# [  1387,  2770)        8054   0.79%  99.53%
# [  2770,  4152)        2074   0.20%  99.73%
# [  4152,  5535)         904   0.09%  99.82%
# [  5535,  6918)         538   0.05%  99.88%
# [  6918,  8300)         311   0.03%  99.91%
# [  8300,  9683)         280   0.03%  99.93%
# [  9683, 11066)         187   0.02%  99.95%
# [ 11066, 12448)         144   0.01%  99.97%
# [ 12448, 13831)         123   0.01%  99.98%
# [ 13831, 15214)          75   0.01%  99.98%
# [ 15214, 16596)          45   0.00%  99.99%
# [ 16596, 17979)          43   0.00%  99.99%
# [ 17979, 19362)          19   0.00% 100.00%
# [ 19362, 20744)          17   0.00% 100.00%
# [ 20744, 22127)          13   0.00% 100.00%
# [ 22127, 23510)           3   0.00% 100.00%
# [ 23510, 24892)           7   0.00% 100.00%
# [ 24892, 26275)           3   0.00% 100.00%
# [ 26275, 27657]           6   0.00% 100.00%
#
# Attribute in nodes:
# 	82120 : RunEntropy [NUMERICAL]
# 	79841 : GrayLevelNonUniformity [NUMERICAL]
# 	78201 : LongRunHighGrayLevelEmphasis [NUMERICAL]
# 	77068 : GrayLevelVariance [NUMERICAL]
# 	70336 : GrayLevelNonUniformityNormalized [NUMERICAL]
# 	65777 : ShortRunLowGrayLevelEmphasis [NUMERICAL]
# 	64028 : ShortRunHighGrayLevelEmphasis [NUMERICAL]
# 	62831 : LongRunLowGrayLevelEmphasis [NUMERICAL]
# 	61808 : RunVariance [NUMERICAL]
# 	60888 : HighGrayLevelRunEmphasis [NUMERICAL]
# 	59673 : LowGrayLevelRunEmphasis [NUMERICAL]
# 	55035 : RunLengthNonUniformityNormalized [NUMERICAL]
# 	53786 : ShortRunEmphasis [NUMERICAL]
# 	53297 : LongRunEmphasis [NUMERICAL]
# 	50155 : RunLengthNonUniformity [NUMERICAL]
# 	47534 : RunPercentage [NUMERICAL]
#
# Attribute in nodes with depth <= 0:
# 	80 : LowGrayLevelRunEmphasis [NUMERICAL]
# 	66 : ShortRunLowGrayLevelEmphasis [NUMERICAL]
# 	57 : LongRunLowGrayLevelEmphasis [NUMERICAL]
# 	32 : HighGrayLevelRunEmphasis [NUMERICAL]
# 	29 : LongRunHighGrayLevelEmphasis [NUMERICAL]
# 	14 : RunEntropy [NUMERICAL]
# 	10 : ShortRunHighGrayLevelEmphasis [NUMERICAL]
# 	9 : GrayLevelNonUniformity [NUMERICAL]
# 	2 : GrayLevelNonUniformityNormalized [NUMERICAL]
# 	1 : RunVariance [NUMERICAL]
#
# Attribute in nodes with depth <= 1:
# 	220 : LongRunHighGrayLevelEmphasis [NUMERICAL]
# 	159 : HighGrayLevelRunEmphasis [NUMERICAL]
# 	138 : ShortRunLowGrayLevelEmphasis [NUMERICAL]
# 	129 : LowGrayLevelRunEmphasis [NUMERICAL]
# 	83 : ShortRunHighGrayLevelEmphasis [NUMERICAL]
# 	74 : LongRunLowGrayLevelEmphasis [NUMERICAL]
# 	49 : RunEntropy [NUMERICAL]
# 	23 : GrayLevelNonUniformity [NUMERICAL]
# 	14 : GrayLevelNonUniformityNormalized [NUMERICAL]
# 	4 : GrayLevelVariance [NUMERICAL]
# 	3 : ShortRunEmphasis [NUMERICAL]
# 	2 : RunVariance [NUMERICAL]
# 	1 : RunPercentage [NUMERICAL]
# 	1 : LongRunEmphasis [NUMERICAL]
#
# Attribute in nodes with depth <= 2:
# 	464 : LongRunHighGrayLevelEmphasis [NUMERICAL]
# 	284 : HighGrayLevelRunEmphasis [NUMERICAL]
# 	237 : ShortRunLowGrayLevelEmphasis [NUMERICAL]
# 	226 : LowGrayLevelRunEmphasis [NUMERICAL]
# 	189 : ShortRunHighGrayLevelEmphasis [NUMERICAL]
# 	140 : LongRunLowGrayLevelEmphasis [NUMERICAL]
# 	123 : RunEntropy [NUMERICAL]
# 	79 : RunVariance [NUMERICAL]
# 	78 : ShortRunEmphasis [NUMERICAL]
# 	64 : LongRunEmphasis [NUMERICAL]
# 	57 : GrayLevelNonUniformity [NUMERICAL]
# 	48 : RunPercentage [NUMERICAL]
# 	40 : RunLengthNonUniformityNormalized [NUMERICAL]
# 	36 : GrayLevelNonUniformityNormalized [NUMERICAL]
# 	22 : RunLengthNonUniformity [NUMERICAL]
# 	13 : GrayLevelVariance [NUMERICAL]
#
# Attribute in nodes with depth <= 3:
# 	922 : LongRunHighGrayLevelEmphasis [NUMERICAL]
# 	545 : HighGrayLevelRunEmphasis [NUMERICAL]
# 	404 : ShortRunHighGrayLevelEmphasis [NUMERICAL]
# 	383 : RunEntropy [NUMERICAL]
# 	379 : ShortRunLowGrayLevelEmphasis [NUMERICAL]
# 	347 : LowGrayLevelRunEmphasis [NUMERICAL]
# 	266 : LongRunLowGrayLevelEmphasis [NUMERICAL]
# 	254 : GrayLevelNonUniformity [NUMERICAL]
# 	162 : ShortRunEmphasis [NUMERICAL]
# 	150 : RunVariance [NUMERICAL]
# 	137 : LongRunEmphasis [NUMERICAL]
# 	126 : RunLengthNonUniformityNormalized [NUMERICAL]
# 	126 : GrayLevelNonUniformityNormalized [NUMERICAL]
# 	114 : GrayLevelVariance [NUMERICAL]
# 	105 : RunPercentage [NUMERICAL]
# 	80 : RunLengthNonUniformity [NUMERICAL]
#
# Attribute in nodes with depth <= 5:
# 	2816 : LongRunHighGrayLevelEmphasis [NUMERICAL]
# 	1720 : RunEntropy [NUMERICAL]
# 	1625 : HighGrayLevelRunEmphasis [NUMERICAL]
# 	1423 : GrayLevelNonUniformity [NUMERICAL]
# 	1310 : ShortRunHighGrayLevelEmphasis [NUMERICAL]
# 	1264 : ShortRunLowGrayLevelEmphasis [NUMERICAL]
# 	1183 : LowGrayLevelRunEmphasis [NUMERICAL]
# 	993 : LongRunLowGrayLevelEmphasis [NUMERICAL]
# 	890 : ShortRunEmphasis [NUMERICAL]
# 	880 : RunLengthNonUniformityNormalized [NUMERICAL]
# 	800 : GrayLevelVariance [NUMERICAL]
# 	786 : RunVariance [NUMERICAL]
# 	769 : GrayLevelNonUniformityNormalized [NUMERICAL]
# 	669 : LongRunEmphasis [NUMERICAL]
# 	637 : RunLengthNonUniformity [NUMERICAL]
# 	617 : RunPercentage [NUMERICAL]
#
# Condition type in nodes:
# 	1022378 : HigherCondition
# Condition type in nodes with depth <= 0:
# 	300 : HigherCondition
# Condition type in nodes with depth <= 1:
# 	900 : HigherCondition
# Condition type in nodes with depth <= 2:
# 	2100 : HigherCondition
# Condition type in nodes with depth <= 3:
# 	4500 : HigherCondition
# Condition type in nodes with depth <= 5:
# 	18382 : HigherCondition
# Node format: NOT_SET
#
# Training OOB:
# 	trees: 1, Out-of-bag evaluation: accuracy:0.814232 logloss:6.69577
# 	trees: 11, Out-of-bag evaluation: accuracy:0.827163 logloss:2.7295
# 	trees: 21, Out-of-bag evaluation: accuracy:0.840087 logloss:1.72238
# 	trees: 31, Out-of-bag evaluation: accuracy:0.844808 logloss:1.34287
# 	trees: 41, Out-of-bag evaluation: accuracy:0.84709 logloss:1.14997
# 	trees: 51, Out-of-bag evaluation: accuracy:0.848243 logloss:1.00928
# 	trees: 61, Out-of-bag evaluation: accuracy:0.849047 logloss:0.926204
# 	trees: 71, Out-of-bag evaluation: accuracy:0.850086 logloss:0.860378
# 	trees: 81, Out-of-bag evaluation: accuracy:0.850307 logloss:0.803586
# 	trees: 91, Out-of-bag evaluation: accuracy:0.850611 logloss:0.757784
# 	trees: 101, Out-of-bag evaluation: accuracy:0.851322 logloss:0.730611
# 	trees: 111, Out-of-bag evaluation: accuracy:0.850751 logloss:0.705318
# 	trees: 121, Out-of-bag evaluation: accuracy:0.851426 logloss:0.679107
# 	trees: 131, Out-of-bag evaluation: accuracy:0.851662 logloss:0.657689
# 	trees: 141, Out-of-bag evaluation: accuracy:0.851803 logloss:0.638861
# 	trees: 151, Out-of-bag evaluation: accuracy:0.851812 logloss:0.621755
# 	trees: 161, Out-of-bag evaluation: accuracy:0.852039 logloss:0.605091
# 	trees: 171, Out-of-bag evaluation: accuracy:0.851896 logloss:0.589738
# 	trees: 181, Out-of-bag evaluation: accuracy:0.85212 logloss:0.578963
# 	trees: 191, Out-of-bag evaluation: accuracy:0.852158 logloss:0.570025
# 	trees: 201, Out-of-bag evaluation: accuracy:0.85215 logloss:0.561351
# 	trees: 211, Out-of-bag evaluation: accuracy:0.852199 logloss:0.558022
# 	trees: 221, Out-of-bag evaluation: accuracy:0.852369 logloss:0.550678
# 	trees: 231, Out-of-bag evaluation: accuracy:0.852421 logloss:0.543338
# 	trees: 241, Out-of-bag evaluation: accuracy:0.852367 logloss:0.536032
# 	trees: 251, Out-of-bag evaluation: accuracy:0.852728 logloss:0.529635
# 	trees: 261, Out-of-bag evaluation: accuracy:0.852831 logloss:0.52196
# 	trees: 271, Out-of-bag evaluation: accuracy:0.85247 logloss:0.516306
# 	trees: 281, Out-of-bag evaluation: accuracy:0.852394 logloss:0.508904
# 	trees: 291, Out-of-bag evaluation: accuracy:0.852217 logloss:0.501318
# 	trees: 300, Out-of-bag evaluation: accuracy:0.852146 logloss:0.498875

# %%
# Model features
model.make_inspector().features()
# Out:
# ["GrayLevelNonUniformity" (1; #0),
#  "GrayLevelNonUniformityNormalized" (1; #1),
#  "GrayLevelVariance" (1; #2),
#  "HighGrayLevelRunEmphasis" (1; #3),
#  "LongRunEmphasis" (1; #4),
#  "LongRunHighGrayLevelEmphasis" (1; #5),
#  "LongRunLowGrayLevelEmphasis" (1; #6),
#  "LowGrayLevelRunEmphasis" (1; #7),
#  "RunEntropy" (1; #8),
#  "RunLengthNonUniformity" (1; #9),
#  "RunLengthNonUniformityNormalized" (1; #10),
#  "RunPercentage" (1; #11),
#  "RunVariance" (1; #12),
#  "ShortRunEmphasis" (1; #13),
#  "ShortRunHighGrayLevelEmphasis" (1; #14),
#  "ShortRunLowGrayLevelEmphasis" (1; #15)]

# %%
# Feature importance
model.make_inspector().variable_importances()
# Out:
# {'INV_MEAN_MIN_DEPTH': [("LongRunHighGrayLevelEmphasis" (1; #5),
#    0.1779363144344327),
#   ("LowGrayLevelRunEmphasis" (1; #7), 0.13704572619353284),
#   ("ShortRunLowGrayLevelEmphasis" (1; #15), 0.13606412621561995),
#   ("HighGrayLevelRunEmphasis" (1; #3), 0.1343696485363823),
#   ("ShortRunHighGrayLevelEmphasis" (1; #14), 0.11890793490414886),
#   ("RunEntropy" (1; #8), 0.11667148158118881),
#   ("LongRunLowGrayLevelEmphasis" (1; #6), 0.10982283871485064),
#   ("GrayLevelNonUniformity" (1; #0), 0.10740373819803883),
#   ("RunVariance" (1; #12), 0.09306014326668695),
#   ("GrayLevelNonUniformityNormalized" (1; #1), 0.09005172951966438),
#   ("LongRunEmphasis" (1; #4), 0.08845470271603949),
#   ("ShortRunEmphasis" (1; #13), 0.087320627186912),
#   ("GrayLevelVariance" (1; #2), 0.08560717355869003),
#   ("RunLengthNonUniformityNormalized" (1; #10), 0.08544008200712382),
#   ("RunPercentage" (1; #11), 0.08476129361045161),
#   ("RunLengthNonUniformity" (1; #9), 0.0817619349202065)],
#  'NUM_AS_ROOT': [("LowGrayLevelRunEmphasis" (1; #7), 80.0),
#   ("ShortRunLowGrayLevelEmphasis" (1; #15), 66.0),
#   ("LongRunLowGrayLevelEmphasis" (1; #6), 57.0),
#   ("HighGrayLevelRunEmphasis" (1; #3), 32.0),
#   ("LongRunHighGrayLevelEmphasis" (1; #5), 29.0),
#   ("RunEntropy" (1; #8), 14.0),
#   ("ShortRunHighGrayLevelEmphasis" (1; #14), 10.0),
#   ("GrayLevelNonUniformity" (1; #0), 9.0),
#   ("GrayLevelNonUniformityNormalized" (1; #1), 2.0),
#   ("RunVariance" (1; #12), 1.0)],
#  'SUM_SCORE': [("LongRunHighGrayLevelEmphasis" (1; #5), 8471447.167032091),
#   ("ShortRunLowGrayLevelEmphasis" (1; #15), 6214780.932661163),
#   ("LowGrayLevelRunEmphasis" (1; #7), 6089688.286030272),
#   ("HighGrayLevelRunEmphasis" (1; #3), 5669665.421984469),
#   ("RunEntropy" (1; #8), 4735045.858271988),
#   ("ShortRunHighGrayLevelEmphasis" (1; #14), 4431688.894976209),
#   ("LongRunLowGrayLevelEmphasis" (1; #6), 4388235.1335209925),
#   ("GrayLevelNonUniformity" (1; #0), 4299445.259878072),
#   ("GrayLevelNonUniformityNormalized" (1; #1), 2546818.5404047766),
#   ("RunVariance" (1; #12), 2531552.2309079897),
#   ("GrayLevelVariance" (1; #2), 2296382.686651736),
#   ("LongRunEmphasis" (1; #4), 2118007.5313327657),
#   ("ShortRunEmphasis" (1; #13), 1961223.3562094246),
#   ("RunLengthNonUniformityNormalized" (1; #10), 1891184.0122333704),
#   ("RunPercentage" (1; #11), 1738591.3266392353),
#   ("RunLengthNonUniformity" (1; #9), 1545127.269859006)],
#  'NUM_NODES': [("RunEntropy" (1; #8), 82120.0),
#   ("GrayLevelNonUniformity" (1; #0), 79841.0),
#   ("LongRunHighGrayLevelEmphasis" (1; #5), 78201.0),
#   ("GrayLevelVariance" (1; #2), 77068.0),
#   ("GrayLevelNonUniformityNormalized" (1; #1), 70336.0),
#   ("ShortRunLowGrayLevelEmphasis" (1; #15), 65777.0),
#   ("ShortRunHighGrayLevelEmphasis" (1; #14), 64028.0),
#   ("LongRunLowGrayLevelEmphasis" (1; #6), 62831.0),
#   ("RunVariance" (1; #12), 61808.0),
#   ("HighGrayLevelRunEmphasis" (1; #3), 60888.0),
#   ("LowGrayLevelRunEmphasis" (1; #7), 59673.0),
#   ("RunLengthNonUniformityNormalized" (1; #10), 55035.0),
#   ("ShortRunEmphasis" (1; #13), 53786.0),
#   ("LongRunEmphasis" (1; #4), 53297.0),
#   ("RunLengthNonUniformity" (1; #9), 50155.0),
#   ("RunPercentage" (1; #11), 47534.0)]}

# %%
# Model self evaluation
model.make_inspector().evaluation()
# Out:
# Evaluation(num_examples=395218, accuracy=0.8521456677240266, loss=0.4988749209230093, rmse=None, ndcg=None, aucs=None, auuc=None, qini=None)

# %%
logs = model.make_inspector().training_logs()

plt.figure(figsize=(12, 4))
plt.subplot(1, 2, 1)
plt.plot([log.num_trees for log in logs], [log.evaluation.accuracy for log in logs])
plt.xlabel("Number of trees")
plt.ylabel("Accuracy (out-of-bag)")
plt.subplot(1, 2, 2)
plt.plot([log.num_trees for log in logs], [log.evaluation.loss for log in logs])
plt.xlabel("Number of trees")
plt.ylabel("Logloss (out-of-bag)")
plt.show()

# %% [markdown]
# Calculate the score of our hold-out validation dataset

# %%
predictions = model.predict(val_ds)
y_true      = validation_data["label"]

from sklearn.metrics import roc_auc_score
ROC_AUC = roc_auc_score(y_true, predictions)
print("The ROC AUC score is %.5f" % ROC_AUC )
# Out:
#  1/57 [..............................] - ETA: 5s
#  3/57 [>.............................] - ETA: 2s
#  5/57 [=>............................] - ETA: 2s
#  7/57 [==>...........................] - ETA: 2s
#  9/57 [===>..........................] - ETA: 2s
# 11/57 [====>.........................] - ETA: 2s
# 13/57 [=====>........................] - ETA: 1s
# 15/57 [======>.......................] - ETA: 1s
# 17/57 [=======>......................] - ETA: 1s
# 19/57 [=========>....................] - ETA: 1s
# 21/57 [==========>...................] - ETA: 1s
# 23/57 [===========>..................] - ETA: 1s
# 25/57 [============>.................] - ETA: 1s
# 27/57 [=============>................] - ETA: 1s
# 29/57 [==============>...............] - ETA: 1s
# 31/57 [===============>..............] - ETA: 1s
# 33/57 [================>.............] - ETA: 0s
# 35/57 [=================>............] - ETA: 0s
# 37/57 [==================>...........] - ETA: 0s
# 39/57 [===================>..........] - ETA: 0s
# 41/57 [====================>.........] - ETA: 0s
# 43/57 [=====================>........] - ETA: 0s
# 45/57 [======================>.......] - ETA: 0s
# 47/57 [=======================>......] - ETA: 0s
# 49/57 [========================>.....] - ETA: 0s
# 51/57 [=========================>....] - ETA: 0s
# 53/57 [==========================>...] - ETA: 0s
# 55/57 [===========================>..] - ETA: 0s
# 57/57 [==============================] - ETA: 0s
# 57/57 [==============================] - 2s 40ms/step
# The ROC AUC score is 0.93827

# %%
# Compute binary classification metrics with sklearn
import numpy as np
from sklearn.metrics import (
    accuracy_score,
    precision_score,
    recall_score,
    f1_score,
    roc_auc_score,
    average_precision_score,
    confusion_matrix,
    classification_report,
    matthews_corrcoef,
    log_loss,
    brier_score_loss,
)

# Get predictions (probabilities or class labels)
preds = model.predict(test_ds)
# If model outputs probabilities, convert to labels by threshold 0.5
if preds.ndim == 2:
    # For TFDF classification, preds may be class probabilities with shape (N, 2)
    if preds.shape[1] == 2:
        pos_probs = preds[:, 1]
    else:
        # If single-probability column (positive class)
        pos_probs = preds[:, -1]
    y_pred = (pos_probs >= 0.5).astype(int)
else:
    # Already class labels
    y_pred = preds.astype(int)
    pos_probs = None

# Ground truth labels (must be 0/1 integers)
y_true = test_data["label"].astype(int).to_numpy()

# Core metrics
metrics = {}
metrics["accuracy"] = accuracy_score(y_true, y_pred)
metrics["precision"] = precision_score(y_true, y_pred, zero_division=0)
metrics["recall"] = recall_score(y_true, y_pred, zero_division=0)
metrics["f1"] = f1_score(y_true, y_pred, zero_division=0)
metrics["mcc"] = matthews_corrcoef(y_true, y_pred)

# Probabilistic metrics (only if we have probabilities)
if pos_probs is not None:
    metrics["roc_auc"] = roc_auc_score(y_true, pos_probs)
    metrics["pr_auc"] = average_precision_score(y_true, pos_probs)
    metrics["log_loss"] = log_loss(y_true, pos_probs, labels=[0,1])
    metrics["brier_score"] = brier_score_loss(y_true, pos_probs)

# Confusion matrix and detailed report
cm = confusion_matrix(y_true, y_pred, labels=[0,1])
report = classification_report(y_true, y_pred, digits=4)

print("Sklearn binary metrics:")
for k, v in metrics.items():
    print(f"{k}: {v:.4f}")
print("\nConfusion matrix:\n", cm)
print("\nClassification report:\n", report)
# Out:
#   1/113 [..............................] - ETA: 11s
#   3/113 [..............................] - ETA: 4s
#   5/113 [>.............................] - ETA: 4s
#   7/113 [>.............................] - ETA: 4s
#   9/113 [=>............................] - ETA: 3s
#  11/113 [=>............................] - ETA: 3s
#  13/113 [==>...........................] - ETA: 3s
#  15/113 [==>...........................] - ETA: 3s
#  17/113 [===>..........................] - ETA: 3s
#  19/113 [====>.........................] - ETA: 3s
#  21/113 [====>.........................] - ETA: 3s
#  23/113 [=====>........................] - ETA: 3s
#  25/113 [=====>........................] - ETA: 3s
#  27/113 [======>.......................] - ETA: 3s
#  29/113 [======>.......................] - ETA: 3s
#  31/113 [=======>......................] - ETA: 3s
#  33/113 [=======>......................] - ETA: 3s
#  35/113 [========>.....................] - ETA: 3s
#  37/113 [========>.....................] - ETA: 3s
#  39/113 [=========>....................] - ETA: 2s
#  41/113 [=========>....................] - ETA: 2s
#  43/113 [==========>...................] - ETA: 2s
#  45/113 [==========>...................] - ETA: 2s
#  47/113 [===========>..................] - ETA: 2s
#  49/113 [============>.................] - ETA: 2s
#  51/113 [============>.................] - ETA: 2s
#  53/113 [=============>................] - ETA: 2s
#  55/113 [=============>................] - ETA: 2s
#  57/113 [==============>...............] - ETA: 2s
#  59/113 [==============>...............] - ETA: 2s
#  61/113 [===============>..............] - ETA: 2s
#  63/113 [===============>..............] - ETA: 1s
#  65/113 [================>.............] - ETA: 1s
#  67/113 [================>.............] - ETA: 1s
#  69/113 [=================>............] - ETA: 1s
#  71/113 [=================>............] - ETA: 1s
#  73/113 [==================>...........] - ETA: 1s
#  75/113 [==================>...........] - ETA: 1s
#  77/113 [===================>..........] - ETA: 1s
#  79/113 [===================>..........] - ETA: 1s
#  81/113 [====================>.........] - ETA: 1s
#  83/113 [=====================>........] - ETA: 1s
#  85/113 [=====================>........] - ETA: 1s
#  87/113 [======================>.......] - ETA: 1s
#  89/113 [======================>.......] - ETA: 0s
#  91/113 [=======================>......] - ETA: 0s
#  93/113 [=======================>......] - ETA: 0s
#  95/113 [========================>.....] - ETA: 0s
#  97/113 [========================>.....] - ETA: 0s
#  99/113 [=========================>....] - ETA: 0s
# 101/113 [=========================>....] - ETA: 0s
# 103/113 [==========================>...] - ETA: 0s
# 105/113 [==========================>...] - ETA: 0s
# 107/113 [===========================>..] - ETA: 0s
# 109/113 [===========================>..] - ETA: 0s
# 111/113 [============================>.] - ETA: 0s
# 113/113 [==============================] - ETA: 0s
# 113/113 [==============================] - 4s 39ms/step
# Sklearn binary metrics:
# accuracy: 0.9120
# precision: 0.4012
# recall: 0.7800
# f1: 0.5299
# mcc: 0.5197
# roc_auc: 0.9386
# pr_auc: 0.6358
# log_loss: 0.2154
# brier_score: 0.0642
#
# Confusion matrix:
#  [[97381  8358]
#  [ 1580  5601]]
#
# Classification report:
#                precision    recall  f1-score   support
#
#            0     0.9840    0.9210    0.9515    105739
#            1     0.4012    0.7800    0.5299      7181
#
#     accuracy                         0.9120    112920
#    macro avg     0.6926    0.8505    0.7407    112920
# weighted avg     0.9470    0.9120    0.9246    112920
