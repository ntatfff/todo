# %%
# Import packages and modules
import numpy  as np
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow_decision_forests as tfdf

from sklearn.model_selection import train_test_split
# Out:
# 2026-07-04 08:18:10.531392: I tensorflow/core/util/port.cc:113] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2026-07-04 08:18:10.592870: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2026-07-04 08:18:15.514118: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
# Check the version of TensorFlow Decision Forests
print("Found TensorFlow Decision Forests v" + tfdf.__version__)
# Out:
# Found TensorFlow Decision Forests v1.9.1

# %%
datasetPath = 'dataset/firstorder/kernel5-radius5/dataset.csv'

# %%
# Parameters
datasetPath = "dataset/glcm/kernel5-radius5/100.dataset.csv"

# %%
# train/validation/test = 70/10/20
dataset = pd.read_csv(datasetPath)

train_data, temp_data = train_test_split(dataset, test_size=0.3, random_state=42)
validation_data, test_data = train_test_split(temp_data, test_size=2/3, random_state=42)

# %%
from sklearn.utils.class_weight import compute_class_weight

# tinh class weight tren tap train
classes = np.array([0, 1])
weights = compute_class_weight(class_weight="balanced", classes=classes, y=train_data["label"])
class_weight = {0: weights[0], 1: weights[1]}

# gan sample_weight cho tung dong
train_data["sample_weight"] = train_data["label"].map(class_weight)
validation_data["sample_weight"] = validation_data["label"].map(class_weight)
test_data["sample_weight"] = test_data["label"].map(class_weight)

# Convert the dataset into a TensorFlow dataset.
train_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    train_data, label="label", weight="sample_weight"
)         
val_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    validation_data, label="label", weight="sample_weight"
)
test_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    test_data, label="label", weight="sample_weight"
)
# Out:
# 2026-07-04 08:18:27.866059: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:984] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2026-07-04 08:18:27.867553: W tensorflow/core/common_runtime/gpu/gpu_device.cc:2251] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...

# %%
import keras

# %%
# %%time

# Train a Gradient Boosted Trees model.
model = tfdf.keras.GradientBoostedTreesModel()

# Add evaluation metrics
model.compile(
    metrics=["accuracy"]
)
model.fit(x=train_ds)

# # Train a Gradient Boosted Trees model.
# model = tfdf.keras.GradientBoostedTreesModel(num_trees=1500)
# model.fit(train_ds)
# Out:
# Use /tmp/tmptik2nh2i as temporary training directory
# Reading training dataset...
# [WARNING 26-07-04 08:18:28.0288 UTC gradient_boosted_trees.cc:1840] "goss_alpha" set but "sampling_method" not equal to "GOSS".
# [WARNING 26-07-04 08:18:28.0292 UTC gradient_boosted_trees.cc:1851] "goss_beta" set but "sampling_method" not equal to "GOSS".
# [WARNING 26-07-04 08:18:28.0292 UTC gradient_boosted_trees.cc:1865] "selective_gradient_boosting_ratio" set but "sampling_method" not equal to "SELGB".
# Training dataset read in 0:00:03.021940. Found 78712 examples.
# Training model...
# Model trained in 0:00:22.225683
# Compiling model...
# [INFO 26-07-04 08:18:53.3090 UTC kernel.cc:1233] Loading model from path /tmp/tmptik2nh2i/model/ with prefix f3ed9565df914f89
# [INFO 26-07-04 08:18:53.3205 UTC quick_scorer_extended.cc:911] The binary was compiled without AVX2 support, but your CPU supports it. Enable it for faster model inference.
# [INFO 26-07-04 08:18:53.3213 UTC abstract_model.cc:1362] Engine "GradientBoostedTreesQuickScorerExtended" built
# [INFO 26-07-04 08:18:53.3213 UTC kernel.cc:1061] Use fast generic engine
# Model compiled.
# CPU times: user 3min 6s, sys: 3.33 s, total: 3min 9s
# Wall time: 28.3 s

# %%
# Evaluate the model
evaluate = model.evaluate(val_ds, return_dict=True)
print()

for name, value in evaluate.items():
    print(f"{name}: {value:.4f}")
# Out:
# WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
#  1/12 [=>............................] - ETA: 32s - loss: 0.0000e+00 - accuracy: 0.9530
# 10/12 [========================>.....] - ETA: 0s - loss: 0.0000e+00 - accuracy: 0.9573
# 12/12 [==============================] - 3s 6ms/step - loss: 0.0000e+00 - accuracy: 0.9564
# loss: 0.0000
# accuracy: 0.9564

# %%
# Model Summary
model.summary()
# Out:
# Model: "gradient_boosted_trees_model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
# =================================================================
# Total params: 1 (1.00 Byte)
# Trainable params: 0 (0.00 Byte)
# Non-trainable params: 1 (1.00 Byte)
# _________________________________________________________________
# Type: "GRADIENT_BOOSTED_TREES"
# Task: CLASSIFICATION
# Label: "__LABEL"
#
# Input Features (24):
# 	Autocorrelation
# 	ClusterProminence
# 	ClusterShade
# 	ClusterTendency
# 	Contrast
# 	Correlation
# 	DifferenceAverage
# 	DifferenceEntropy
# 	DifferenceVariance
# 	Id
# 	Idm
# 	Idmn
# 	Idn
# 	Imc1
# 	Imc2
# 	InverseVariance
# 	JointAverage
# 	JointEnergy
# 	JointEntropy
# 	MCC
# 	MaximumProbability
# 	SumAverage
# 	SumEntropy
# 	SumSquares
#
# Trained with weights
#
# Variable Importance: INV_MEAN_MIN_DEPTH:
#     1.               "Idmn"  0.240027 ################
#     2.    "Autocorrelation"  0.221669 ###########
#     3.                "Idn"  0.217522 ##########
#     4.       "ClusterShade"  0.205622 #######
#     5.               "Imc1"  0.203930 #######
#     6.        "Correlation"  0.197947 #####
#     7.         "SumAverage"  0.196696 #####
#     8.       "JointAverage"  0.196214 #####
#     9. "DifferenceVariance"  0.191572 ####
#    10.    "InverseVariance"  0.190854 ####
#    11.  "DifferenceEntropy"  0.188299 ###
#    12.  "DifferenceAverage"  0.184282 ##
#    13.           "Contrast"  0.183259 ##
#    14.                "MCC"  0.178123
#    15.                 "Id"  0.177848
#    16. "MaximumProbability"  0.177662
#    17.  "ClusterProminence"  0.177487
#    18.                "Idm"  0.177311
#    19.         "SumEntropy"  0.176730
#    20.               "Imc2"  0.176352
#    21.       "JointEntropy"  0.175792
#    22.        "JointEnergy"  0.174915
#    23.         "SumSquares"  0.174500
#    24.    "ClusterTendency"  0.174217
#
# Variable Importance: NUM_AS_ROOT:
#     1.               "Idmn" 65.000000 ################
#     2.                "Idn" 36.000000 ########
#     3.    "Autocorrelation" 35.000000 ########
#     4.               "Imc1" 31.000000 #######
#     5.        "Correlation" 23.000000 #####
#     6.       "JointAverage" 18.000000 ####
#     7.         "SumAverage" 17.000000 ####
#     8. "DifferenceVariance"  7.000000 #
#     9.       "ClusterShade"  4.000000
#    10.           "Contrast"  4.000000
#    11.                "MCC"  4.000000
#    12.  "DifferenceEntropy"  3.000000
#    13.  "DifferenceAverage"  1.000000
#    14.               "Imc2"  1.000000
#    15.    "InverseVariance"  1.000000
#
# Variable Importance: NUM_NODES:
#     1.    "Autocorrelation" 672.000000 ################
#     2.       "ClusterShade" 543.000000 ############
#     3.               "Idmn" 521.000000 ###########
#     4.                "Idn" 493.000000 ###########
#     5.         "SumAverage" 337.000000 ######
#     6.               "Imc1" 335.000000 ######
#     7.       "JointAverage" 326.000000 ######
#     8.    "InverseVariance" 316.000000 ######
#     9.        "Correlation" 285.000000 #####
#    10. "DifferenceVariance" 276.000000 #####
#    11.  "DifferenceEntropy" 270.000000 #####
#    12. "MaximumProbability" 183.000000 ##
#    13.           "Contrast" 182.000000 ##
#    14.         "SumEntropy" 181.000000 ##
#    15.  "ClusterProminence" 167.000000 ##
#    16.               "Imc2" 164.000000 ##
#    17.                "MCC" 162.000000 ##
#    18.  "DifferenceAverage" 156.000000 #
#    19.       "JointEntropy" 131.000000 #
#    20.                "Idm" 125.000000 #
#    21.                 "Id" 110.000000
#    22.         "SumSquares" 98.000000
#    23.    "ClusterTendency" 93.000000
#    24.        "JointEnergy" 87.000000
#
# Variable Importance: SUM_SCORE:
#     1.    "Autocorrelation" 31196.769209 ################
#     2.               "Imc1" 11364.963738 #####
#     3.    "InverseVariance" 10778.817069 #####
#     4.         "SumAverage" 4372.946860 ##
#     5.       "JointAverage" 3715.756561 #
#     6.                "Idn" 3526.983758 #
#     7. "DifferenceVariance" 3389.443354 #
#     8.               "Idmn" 3070.111506 #
#     9.        "Correlation" 2657.220864 #
#    10.  "DifferenceEntropy" 1798.566206
#    11.       "ClusterShade" 1346.724390
#    12.           "Contrast" 887.916043
#    13.                "Idm" 593.339831
#    14.  "DifferenceAverage" 572.367870
#    15.         "SumEntropy" 554.155059
#    16. "MaximumProbability" 487.072306
#    17.                "MCC" 427.386049
#    18.                 "Id" 358.462421
#    19.               "Imc2" 334.943495
#    20.  "ClusterProminence" 305.409381
#    21.       "JointEntropy" 230.369413
#    22.        "JointEnergy" 214.315953
#    23.         "SumSquares" 201.569134
#    24.    "ClusterTendency" 161.453787
#
#
#
# Loss: BINOMIAL_LOG_LIKELIHOOD
# Validation loss value: 0.342353
# Number of trees per iteration: 1
# Node format: NOT_SET
# Number of trees: 250
# Total number of nodes: 12676
#
# Number of nodes by tree:
# Count: 250 Average: 50.704 StdDev: 9.14376
# Min: 25 Max: 63 Ignored: 0
# ----------------------------------------------
# [ 25, 26)  1   0.40%   0.40%
# [ 26, 28)  1   0.40%   0.80%
# [ 28, 30)  4   1.60%   2.40% #
# [ 30, 32)  1   0.40%   2.80%
# [ 32, 34)  2   0.80%   3.60% #
# [ 34, 36)  9   3.60%   7.20% ###
# [ 36, 38)  5   2.00%   9.20% ##
# [ 38, 40) 10   4.00%  13.20% ####
# [ 40, 42) 20   8.00%  21.20% #######
# [ 42, 44) 11   4.40%  25.60% ####
# [ 44, 46) 17   6.80%  32.40% ######
# [ 46, 48) 13   5.20%  37.60% #####
# [ 48, 50) 19   7.60%  45.20% #######
# [ 50, 52)  9   3.60%  48.80% ###
# [ 52, 54) 17   6.80%  55.60% ######
# [ 54, 56) 23   9.20%  64.80% ########
# [ 56, 58) 25  10.00%  74.80% #########
# [ 58, 60) 14   5.60%  80.40% #####
# [ 60, 62) 21   8.40%  88.80% ########
# [ 62, 63] 28  11.20% 100.00% ##########
#
# Depth by leafs:
# Count: 6463 Average: 4.84868 StdDev: 0.516479
# Min: 1 Max: 5 Ignored: 0
# ----------------------------------------------
# [ 1, 2)    4   0.06%   0.06%
# [ 2, 3)   92   1.42%   1.49%
# [ 3, 4)  147   2.27%   3.76%
# [ 4, 5)  392   6.07%   9.83% #
# [ 5, 5] 5828  90.17% 100.00% ##########
#
# Number of training obs by leaf:
# Count: 6463 Average: 2740.21 StdDev: 7498.73
# Min: 5 Max: 69736 Ignored: 0
# ----------------------------------------------
# [     5,  3491) 5411  83.72%  83.72% ##########
# [  3491,  6978)  405   6.27%  89.99% #
# [  6978, 10464)  164   2.54%  92.53%
# [ 10464, 13951)  120   1.86%  94.38%
# [ 13951, 17438)   86   1.33%  95.71%
# [ 17438, 20924)   67   1.04%  96.75%
# [ 20924, 24411)   33   0.51%  97.26%
# [ 24411, 27897)   31   0.48%  97.74%
# [ 27897, 31384)   22   0.34%  98.08%
# [ 31384, 34871)   23   0.36%  98.44%
# [ 34871, 38357)   17   0.26%  98.70%
# [ 38357, 41844)   13   0.20%  98.90%
# [ 41844, 45330)   20   0.31%  99.21%
# [ 45330, 48817)   11   0.17%  99.38%
# [ 48817, 52304)   10   0.15%  99.54%
# [ 52304, 55790)   10   0.15%  99.69%
# [ 55790, 59277)    7   0.11%  99.80%
# [ 59277, 62763)    4   0.06%  99.86%
# [ 62763, 66250)    7   0.11%  99.97%
# [ 66250, 69736]    2   0.03% 100.00%
#
# Attribute in nodes:
# 	672 : Autocorrelation [NUMERICAL]
# 	543 : ClusterShade [NUMERICAL]
# 	521 : Idmn [NUMERICAL]
# 	493 : Idn [NUMERICAL]
# 	337 : SumAverage [NUMERICAL]
# 	335 : Imc1 [NUMERICAL]
# 	326 : JointAverage [NUMERICAL]
# 	316 : InverseVariance [NUMERICAL]
# 	285 : Correlation [NUMERICAL]
# 	276 : DifferenceVariance [NUMERICAL]
# 	270 : DifferenceEntropy [NUMERICAL]
# 	183 : MaximumProbability [NUMERICAL]
# 	182 : Contrast [NUMERICAL]
# 	181 : SumEntropy [NUMERICAL]
# 	167 : ClusterProminence [NUMERICAL]
# 	164 : Imc2 [NUMERICAL]
# 	162 : MCC [NUMERICAL]
# 	156 : DifferenceAverage [NUMERICAL]
# 	131 : JointEntropy [NUMERICAL]
# 	125 : Idm [NUMERICAL]
# 	110 : Id [NUMERICAL]
# 	98 : SumSquares [NUMERICAL]
# 	93 : ClusterTendency [NUMERICAL]
# 	87 : JointEnergy [NUMERICAL]
#
# Attribute in nodes with depth <= 0:
# 	65 : Idmn [NUMERICAL]
# 	36 : Idn [NUMERICAL]
# 	35 : Autocorrelation [NUMERICAL]
# 	31 : Imc1 [NUMERICAL]
# 	23 : Correlation [NUMERICAL]
# 	18 : JointAverage [NUMERICAL]
# 	17 : SumAverage [NUMERICAL]
# 	7 : DifferenceVariance [NUMERICAL]
# 	4 : MCC [NUMERICAL]
# 	4 : Contrast [NUMERICAL]
# 	4 : ClusterShade [NUMERICAL]
# 	3 : DifferenceEntropy [NUMERICAL]
# 	1 : InverseVariance [NUMERICAL]
# 	1 : Imc2 [NUMERICAL]
# 	1 : DifferenceAverage [NUMERICAL]
#
# Attribute in nodes with depth <= 1:
# 	108 : Idmn [NUMERICAL]
# 	78 : ClusterShade [NUMERICAL]
# 	75 : Autocorrelation [NUMERICAL]
# 	71 : Idn [NUMERICAL]
# 	65 : Imc1 [NUMERICAL]
# 	42 : Correlation [NUMERICAL]
# 	41 : SumAverage [NUMERICAL]
# 	40 : DifferenceVariance [NUMERICAL]
# 	36 : JointAverage [NUMERICAL]
# 	36 : InverseVariance [NUMERICAL]
# 	33 : DifferenceEntropy [NUMERICAL]
# 	32 : DifferenceAverage [NUMERICAL]
# 	28 : Contrast [NUMERICAL]
# 	17 : Id [NUMERICAL]
# 	10 : Idm [NUMERICAL]
# 	6 : MaximumProbability [NUMERICAL]
# 	6 : ClusterProminence [NUMERICAL]
# 	5 : MCC [NUMERICAL]
# 	4 : JointEntropy [NUMERICAL]
# 	4 : Imc2 [NUMERICAL]
# 	3 : SumEntropy [NUMERICAL]
# 	3 : JointEnergy [NUMERICAL]
# 	2 : ClusterTendency [NUMERICAL]
# 	1 : SumSquares [NUMERICAL]
#
# Attribute in nodes with depth <= 2:
# 	203 : Autocorrelation [NUMERICAL]
# 	166 : Idmn [NUMERICAL]
# 	158 : ClusterShade [NUMERICAL]
# 	126 : Idn [NUMERICAL]
# 	105 : Imc1 [NUMERICAL]
# 	104 : InverseVariance [NUMERICAL]
# 	92 : JointAverage [NUMERICAL]
# 	90 : Correlation [NUMERICAL]
# 	86 : SumAverage [NUMERICAL]
# 	82 : DifferenceVariance [NUMERICAL]
# 	74 : DifferenceEntropy [NUMERICAL]
# 	52 : DifferenceAverage [NUMERICAL]
# 	49 : Contrast [NUMERICAL]
# 	35 : MaximumProbability [NUMERICAL]
# 	31 : ClusterProminence [NUMERICAL]
# 	29 : Idm [NUMERICAL]
# 	29 : Id [NUMERICAL]
# 	27 : MCC [NUMERICAL]
# 	22 : JointEntropy [NUMERICAL]
# 	21 : SumEntropy [NUMERICAL]
# 	21 : Imc2 [NUMERICAL]
# 	20 : JointEnergy [NUMERICAL]
# 	14 : ClusterTendency [NUMERICAL]
# 	10 : SumSquares [NUMERICAL]
#
# Attribute in nodes with depth <= 3:
# 	380 : Autocorrelation [NUMERICAL]
# 	309 : Idmn [NUMERICAL]
# 	296 : ClusterShade [NUMERICAL]
# 	255 : Idn [NUMERICAL]
# 	195 : Imc1 [NUMERICAL]
# 	183 : InverseVariance [NUMERICAL]
# 	173 : SumAverage [NUMERICAL]
# 	172 : JointAverage [NUMERICAL]
# 	158 : Correlation [NUMERICAL]
# 	157 : DifferenceEntropy [NUMERICAL]
# 	147 : DifferenceVariance [NUMERICAL]
# 	98 : Contrast [NUMERICAL]
# 	91 : DifferenceAverage [NUMERICAL]
# 	90 : MaximumProbability [NUMERICAL]
# 	82 : ClusterProminence [NUMERICAL]
# 	78 : MCC [NUMERICAL]
# 	74 : SumEntropy [NUMERICAL]
# 	67 : Imc2 [NUMERICAL]
# 	63 : Idm [NUMERICAL]
# 	55 : Id [NUMERICAL]
# 	48 : JointEntropy [NUMERICAL]
# 	47 : JointEnergy [NUMERICAL]
# 	44 : SumSquares [NUMERICAL]
# 	37 : ClusterTendency [NUMERICAL]
#
# Attribute in nodes with depth <= 5:
# 	672 : Autocorrelation [NUMERICAL]
# 	543 : ClusterShade [NUMERICAL]
# 	521 : Idmn [NUMERICAL]
# 	493 : Idn [NUMERICAL]
# 	337 : SumAverage [NUMERICAL]
# 	335 : Imc1 [NUMERICAL]
# 	326 : JointAverage [NUMERICAL]
# 	316 : InverseVariance [NUMERICAL]
# 	285 : Correlation [NUMERICAL]
# 	276 : DifferenceVariance [NUMERICAL]
# 	270 : DifferenceEntropy [NUMERICAL]
# 	183 : MaximumProbability [NUMERICAL]
# 	182 : Contrast [NUMERICAL]
# 	181 : SumEntropy [NUMERICAL]
# 	167 : ClusterProminence [NUMERICAL]
# 	164 : Imc2 [NUMERICAL]
# 	162 : MCC [NUMERICAL]
# 	156 : DifferenceAverage [NUMERICAL]
# 	131 : JointEntropy [NUMERICAL]
# 	125 : Idm [NUMERICAL]
# 	110 : Id [NUMERICAL]
# 	98 : SumSquares [NUMERICAL]
# 	93 : ClusterTendency [NUMERICAL]
# 	87 : JointEnergy [NUMERICAL]
#
# Condition type in nodes:
# 	6213 : HigherCondition
# Condition type in nodes with depth <= 0:
# 	250 : HigherCondition
# Condition type in nodes with depth <= 1:
# 	746 : HigherCondition
# Condition type in nodes with depth <= 2:
# 	1646 : HigherCondition
# Condition type in nodes with depth <= 3:
# 	3299 : HigherCondition
# Condition type in nodes with depth <= 5:
# 	6213 : HigherCondition
#
# Training logs:
# Number of iteration to final model: 250
# 	Iter:1 train-loss:1.270307 valid-loss:1.271487  train-accuracy:0.872676 valid-accuracy:0.867015
# 	Iter:2 train-loss:1.174988 valid-loss:1.177258  train-accuracy:0.876340 valid-accuracy:0.871916
# 	Iter:3 train-loss:1.095248 valid-loss:1.098706  train-accuracy:0.874614 valid-accuracy:0.871822
# 	Iter:4 train-loss:1.026684 valid-loss:1.032932  train-accuracy:0.880712 valid-accuracy:0.876059
# 	Iter:5 train-loss:0.967404 valid-loss:0.974424  train-accuracy:0.883917 valid-accuracy:0.882984
# 	Iter:6 train-loss:0.916114 valid-loss:0.925831  train-accuracy:0.883693 valid-accuracy:0.882728
# 	Iter:16 train-loss:0.627301 valid-loss:0.646381  train-accuracy:0.897086 valid-accuracy:0.898101
# 	Iter:26 train-loss:0.504055 valid-loss:0.536528  train-accuracy:0.913809 valid-accuracy:0.910239
# 	Iter:36 train-loss:0.427111 valid-loss:0.472048  train-accuracy:0.926021 valid-accuracy:0.917175
# 	Iter:46 train-loss:0.379774 valid-loss:0.438206  train-accuracy:0.935099 valid-accuracy:0.921563
# 	Iter:56 train-loss:0.344083 valid-loss:0.412944  train-accuracy:0.941493 valid-accuracy:0.925368
# 	Iter:66 train-loss:0.319429 valid-loss:0.397169  train-accuracy:0.944121 valid-accuracy:0.927661
# 	Iter:76 train-loss:0.303185 valid-loss:0.386594  train-accuracy:0.946742 valid-accuracy:0.928569
# 	Iter:86 train-loss:0.287930 valid-loss:0.377827  train-accuracy:0.949651 valid-accuracy:0.932514
# 	Iter:96 train-loss:0.275877 valid-loss:0.371949  train-accuracy:0.952045 valid-accuracy:0.932049
# 	Iter:106 train-loss:0.263801 valid-loss:0.365706  train-accuracy:0.954663 valid-accuracy:0.929780
# 	Iter:116 train-loss:0.255372 valid-loss:0.362045  train-accuracy:0.957070 valid-accuracy:0.930955
# 	Iter:126 train-loss:0.247308 valid-loss:0.357632  train-accuracy:0.959243 valid-accuracy:0.928965
# 	Iter:136 train-loss:0.239594 valid-loss:0.354428  train-accuracy:0.960592 valid-accuracy:0.929384
# 	Iter:146 train-loss:0.233034 valid-loss:0.352083  train-accuracy:0.961896 valid-accuracy:0.930082
# 	Iter:156 train-loss:0.226347 valid-loss:0.350999  train-accuracy:0.963237 valid-accuracy:0.929943
# 	Iter:166 train-loss:0.219956 valid-loss:0.349367  train-accuracy:0.965116 valid-accuracy:0.929733
# 	Iter:176 train-loss:0.214798 valid-loss:0.347757  train-accuracy:0.966510 valid-accuracy:0.931048
# 	Iter:186 train-loss:0.210012 valid-loss:0.346908  train-accuracy:0.967669 valid-accuracy:0.931258
# 	Iter:196 train-loss:0.205659 valid-loss:0.345772  train-accuracy:0.969061 valid-accuracy:0.930164
# 	Iter:206 train-loss:0.200134 valid-loss:0.344521  train-accuracy:0.970603 valid-accuracy:0.931270
# 	Iter:216 train-loss:0.196460 valid-loss:0.343979  train-accuracy:0.971416 valid-accuracy:0.929547
# 	Iter:226 train-loss:0.192120 valid-loss:0.343380  train-accuracy:0.972630 valid-accuracy:0.928035
# 	Iter:236 train-loss:0.187990 valid-loss:0.344017  train-accuracy:0.973503 valid-accuracy:0.929140
# 	Iter:246 train-loss:0.184403 valid-loss:0.343293  train-accuracy:0.974158 valid-accuracy:0.927418
# 	Iter:256 train-loss:0.180796 valid-loss:0.343088  train-accuracy:0.974866 valid-accuracy:0.929699
# 	Iter:266 train-loss:0.176503 valid-loss:0.343593  train-accuracy:0.976244 valid-accuracy:0.930944
# 	Iter:276 train-loss:0.173270 valid-loss:0.344578  train-accuracy:0.976855 valid-accuracy:0.930118

# %%
# Model features
model.make_inspector().features()
# Out:
# ["Autocorrelation" (1; #0),
#  "ClusterProminence" (1; #1),
#  "ClusterShade" (1; #2),
#  "ClusterTendency" (1; #3),
#  "Contrast" (1; #4),
#  "Correlation" (1; #5),
#  "DifferenceAverage" (1; #6),
#  "DifferenceEntropy" (1; #7),
#  "DifferenceVariance" (1; #8),
#  "Id" (1; #9),
#  "Idm" (1; #10),
#  "Idmn" (1; #11),
#  "Idn" (1; #12),
#  "Imc1" (1; #13),
#  "Imc2" (1; #14),
#  "InverseVariance" (1; #15),
#  "JointAverage" (1; #16),
#  "JointEnergy" (1; #17),
#  "JointEntropy" (1; #18),
#  "MCC" (1; #19),
#  "MaximumProbability" (1; #20),
#  "SumAverage" (1; #21),
#  "SumEntropy" (1; #22),
#  "SumSquares" (1; #23)]

# %%
# Feature importance
model.make_inspector().variable_importances()
# Out:
# {'INV_MEAN_MIN_DEPTH': [("Idmn" (1; #11), 0.24002700340885674),
#   ("Autocorrelation" (1; #0), 0.2216685330540827),
#   ("Idn" (1; #12), 0.21752204738268616),
#   ("ClusterShade" (1; #2), 0.2056215839950475),
#   ("Imc1" (1; #13), 0.20393016612191175),
#   ("Correlation" (1; #5), 0.19794739919329768),
#   ("SumAverage" (1; #21), 0.19669585024192943),
#   ("JointAverage" (1; #16), 0.19621356434000153),
#   ("DifferenceVariance" (1; #8), 0.19157225779965883),
#   ("InverseVariance" (1; #15), 0.19085429230653161),
#   ("DifferenceEntropy" (1; #7), 0.1882993572833892),
#   ("DifferenceAverage" (1; #6), 0.18428160091236032),
#   ("Contrast" (1; #4), 0.18325850758713635),
#   ("MCC" (1; #19), 0.1781233439937652),
#   ("Id" (1; #9), 0.17784754236718),
#   ("MaximumProbability" (1; #20), 0.1776617168831296),
#   ("ClusterProminence" (1; #1), 0.1774869924821555),
#   ("Idm" (1; #10), 0.17731079399694846),
#   ("SumEntropy" (1; #22), 0.176729860868014),
#   ("Imc2" (1; #14), 0.17635232949533958),
#   ("JointEntropy" (1; #18), 0.1757923357425265),
#   ("JointEnergy" (1; #17), 0.17491462279171116),
#   ("SumSquares" (1; #23), 0.17449991808988857),
#   ("ClusterTendency" (1; #3), 0.1742170902155614)],
#  'NUM_AS_ROOT': [("Idmn" (1; #11), 65.0),
#   ("Idn" (1; #12), 36.0),
#   ("Autocorrelation" (1; #0), 35.0),
#   ("Imc1" (1; #13), 31.0),
#   ("Correlation" (1; #5), 23.0),
#   ("JointAverage" (1; #16), 18.0),
#   ("SumAverage" (1; #21), 17.0),
#   ("DifferenceVariance" (1; #8), 7.0),
#   ("ClusterShade" (1; #2), 4.0),
#   ("Contrast" (1; #4), 4.0),
#   ("MCC" (1; #19), 4.0),
#   ("DifferenceEntropy" (1; #7), 3.0),
#   ("DifferenceAverage" (1; #6), 1.0),
#   ("Imc2" (1; #14), 1.0),
#   ("InverseVariance" (1; #15), 1.0)],
#  'SUM_SCORE': [("Autocorrelation" (1; #0), 31196.769209065846),
#   ("Imc1" (1; #13), 11364.963737899921),
#   ("InverseVariance" (1; #15), 10778.81706902611),
#   ("SumAverage" (1; #21), 4372.946859871578),
#   ("JointAverage" (1; #16), 3715.756560680404),
#   ("Idn" (1; #12), 3526.983757698519),
#   ("DifferenceVariance" (1; #8), 3389.4433543059745),
#   ("Idmn" (1; #11), 3070.111505641172),
#   ("Correlation" (1; #5), 2657.2208635632846),
#   ("DifferenceEntropy" (1; #7), 1798.5662063635684),
#   ("ClusterShade" (1; #2), 1346.724390437289),
#   ("Contrast" (1; #4), 887.9160428321294),
#   ("Idm" (1; #10), 593.339830834759),
#   ("DifferenceAverage" (1; #6), 572.3678699028792),
#   ("SumEntropy" (1; #22), 554.1550592558987),
#   ("MaximumProbability" (1; #20), 487.07230614344974),
#   ("MCC" (1; #19), 427.38604910301046),
#   ("Id" (1; #9), 358.4624208405615),
#   ("Imc2" (1; #14), 334.9434946397647),
#   ("ClusterProminence" (1; #1), 305.4093814891404),
#   ("JointEntropy" (1; #18), 230.3694129248128),
#   ("JointEnergy" (1; #17), 214.3159529673949),
#   ("SumSquares" (1; #23), 201.56913368198767),
#   ("ClusterTendency" (1; #3), 161.45378686284235)],
#  'NUM_NODES': [("Autocorrelation" (1; #0), 672.0),
#   ("ClusterShade" (1; #2), 543.0),
#   ("Idmn" (1; #11), 521.0),
#   ("Idn" (1; #12), 493.0),
#   ("SumAverage" (1; #21), 337.0),
#   ("Imc1" (1; #13), 335.0),
#   ("JointAverage" (1; #16), 326.0),
#   ("InverseVariance" (1; #15), 316.0),
#   ("Correlation" (1; #5), 285.0),
#   ("DifferenceVariance" (1; #8), 276.0),
#   ("DifferenceEntropy" (1; #7), 270.0),
#   ("MaximumProbability" (1; #20), 183.0),
#   ("Contrast" (1; #4), 182.0),
#   ("SumEntropy" (1; #22), 181.0),
#   ("ClusterProminence" (1; #1), 167.0),
#   ("Imc2" (1; #14), 164.0),
#   ("MCC" (1; #19), 162.0),
#   ("DifferenceAverage" (1; #6), 156.0),
#   ("JointEntropy" (1; #18), 131.0),
#   ("Idm" (1; #10), 125.0),
#   ("Id" (1; #9), 110.0),
#   ("SumSquares" (1; #23), 98.0),
#   ("ClusterTendency" (1; #3), 93.0),
#   ("JointEnergy" (1; #17), 87.0)]}

# %%
# Model self evaluation
model.make_inspector().evaluation()
# Out:
# Evaluation(num_examples=None, accuracy=0.9303156137466431, loss=0.34235331416130066, rmse=None, ndcg=None, aucs=None, auuc=None, qini=None)

# %%
logs = model.make_inspector().training_logs()

plt.figure(figsize=(12, 4))
plt.subplot(1, 2, 1)
plt.plot([log.num_trees for log in logs], [log.evaluation.accuracy for log in logs])
plt.xlabel("Number of trees")
plt.ylabel("Accuracy (out-of-bag)")
plt.subplot(1, 2, 2)
plt.plot([log.num_trees for log in logs], [log.evaluation.loss for log in logs])
plt.xlabel("Number of trees")
plt.ylabel("Logloss (out-of-bag)")
plt.show()

# %% [markdown]
# Calculate the score of our hold-out validation dataset

# %%
predictions = model.predict(val_ds)
y_true      = validation_data["label"]

from sklearn.metrics import roc_auc_score
ROC_AUC = roc_auc_score(y_true, predictions)
print("The ROC AUC score is %.5f" % ROC_AUC )
# Out:
#  1/12 [=>............................] - ETA: 0s
#  9/12 [=====================>........] - ETA: 0s
# 12/12 [==============================] - 0s 6ms/step
# The ROC AUC score is 0.97946

# %%
# Compute binary classification metrics with sklearn
import numpy as np
from sklearn.metrics import (
    accuracy_score,
    precision_score,
    recall_score,
    f1_score,
    roc_auc_score,
    average_precision_score,
    confusion_matrix,
    classification_report,
    matthews_corrcoef,
    log_loss,
    brier_score_loss,
)

# Get predictions (probabilities or class labels)
preds = model.predict(test_ds)
# If model outputs probabilities, convert to labels by threshold 0.5
if preds.ndim == 2:
    # For TFDF classification, preds may be class probabilities with shape (N, 2)
    if preds.shape[1] == 2:
        pos_probs = preds[:, 1]
    else:
        # If single-probability column (positive class)
        pos_probs = preds[:, -1]
    y_pred = (pos_probs >= 0.5).astype(int)
else:
    # Already class labels
    y_pred = preds.astype(int)
    pos_probs = None

# Ground truth labels (must be 0/1 integers)
y_true = test_data["label"].astype(int).to_numpy()

# Core metrics
metrics = {}
metrics["accuracy"] = accuracy_score(y_true, y_pred)
metrics["precision"] = precision_score(y_true, y_pred, zero_division=0)
metrics["recall"] = recall_score(y_true, y_pred, zero_division=0)
metrics["f1"] = f1_score(y_true, y_pred, zero_division=0)
metrics["mcc"] = matthews_corrcoef(y_true, y_pred)

# Probabilistic metrics (only if we have probabilities)
if pos_probs is not None:
    metrics["roc_auc"] = roc_auc_score(y_true, pos_probs)
    metrics["pr_auc"] = average_precision_score(y_true, pos_probs)
    metrics["log_loss"] = log_loss(y_true, pos_probs, labels=[0,1])
    metrics["brier_score"] = brier_score_loss(y_true, pos_probs)

# Confusion matrix and detailed report
cm = confusion_matrix(y_true, y_pred, labels=[0,1])
report = classification_report(y_true, y_pred, digits=4)

print("Sklearn binary metrics:")
for k, v in metrics.items():
    print(f"{k}: {v:.4f}")
print("\nConfusion matrix:\n", cm)
print("\nClassification report:\n", report)
# Out:
#  1/23 [>.............................] - ETA: 1s
# 10/23 [============>.................] - ETA: 0s
# 19/23 [=======================>......] - ETA: 0s
# 23/23 [==============================] - 0s 6ms/step
# Sklearn binary metrics:
# accuracy: 0.9583
# precision: 0.6531
# recall: 0.9067
# f1: 0.7593
# mcc: 0.7491
# roc_auc: 0.9834
# pr_auc: 0.8923
# log_loss: 0.1190
# brier_score: 0.0326
#
# Confusion matrix:
#  [[20075   785]
#  [  152  1478]]
#
# Classification report:
#                precision    recall  f1-score   support
#
#            0     0.9925    0.9624    0.9772     20860
#            1     0.6531    0.9067    0.7593      1630
#
#     accuracy                         0.9583     22490
#    macro avg     0.8228    0.9346    0.8683     22490
# weighted avg     0.9679    0.9583    0.9614     22490
