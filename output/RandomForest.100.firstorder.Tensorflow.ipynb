# %%
# Import packages and modules
import numpy  as np
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow_decision_forests as tfdf

from sklearn.model_selection import train_test_split
# Out:
# 2026-07-04 07:42:39.095895: I tensorflow/core/util/port.cc:113] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2026-07-04 07:42:39.137390: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2026-07-04 07:42:43.545474: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
# Check the version of TensorFlow Decision Forests
print("Found TensorFlow Decision Forests v" + tfdf.__version__)
# Out:
# Found TensorFlow Decision Forests v1.9.1

# %%
datasetPath = 'dataset/firstorder/kernel5-radius5/dataset.csv'

# %%
# Parameters
datasetPath = "dataset/firstorder/kernel5-radius5/100.dataset.csv"

# %%
# train/validation/test = 70/10/20
dataset = pd.read_csv(datasetPath)

train_data, temp_data = train_test_split(dataset, test_size=0.3, random_state=42)
validation_data, test_data = train_test_split(temp_data, test_size=2/3, random_state=42)

# %%
from sklearn.utils.class_weight import compute_class_weight

# tinh class weight tren tap train
classes = np.array([0, 1])
weights = compute_class_weight(class_weight="balanced", classes=classes, y=train_data["label"])
class_weight = {0: weights[0], 1: weights[1]}

# gan sample_weight cho tung dong
train_data["sample_weight"] = train_data["label"].map(class_weight)
validation_data["sample_weight"] = validation_data["label"].map(class_weight)
test_data["sample_weight"] = test_data["label"].map(class_weight)

# Convert the dataset into a TensorFlow dataset.
train_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    train_data, label="label", weight="sample_weight"
)         
val_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    validation_data, label="label", weight="sample_weight"
)
test_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    test_data, label="label", weight="sample_weight"
)
# Out:
# 2026-07-04 07:42:55.674406: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:984] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2026-07-04 07:42:55.675774: W tensorflow/core/common_runtime/gpu/gpu_device.cc:2251] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...

# %%
import keras

# %%
# %%time

# Train a Random Forest model.
model = tfdf.keras.RandomForestModel()

# Add evaluation metrics
model.compile(
    metrics=["accuracy"]
)
model.fit(x=train_ds)

# # Train a Gradient Boosted Trees model.
# model = tfdf.keras.GradientBoostedTreesModel(num_trees=1500)
# model.fit(train_ds)
# Out:
# Use /tmp/tmpz7xmpg5l as temporary training directory
# Reading training dataset...
# Training dataset read in 0:00:04.140652. Found 78712 examples.
# Training model...
# [INFO 26-07-04 07:43:07.7997 UTC kernel.cc:1233] Loading model from path /tmp/tmpz7xmpg5l/model/ with prefix 879dde61d7dc4518
# Model trained in 0:00:08.769397
# Compiling model...
# [INFO 26-07-04 07:43:08.6376 UTC decision_forest.cc:734] Model loaded with 300 root(s), 682954 node(s), and 18 input feature(s).
# [INFO 26-07-04 07:43:08.6377 UTC abstract_model.cc:1362] Engine "RandomForestOptPred" built
# [INFO 26-07-04 07:43:08.6377 UTC kernel.cc:1061] Use fast generic engine
# Model compiled.
# CPU times: user 1min 36s, sys: 970 ms, total: 1min 37s
# Wall time: 16.1 s

# %%
# Evaluate the model
evaluate = model.evaluate(val_ds, return_dict=True)
print()

for name, value in evaluate.items():
    print(f"{name}: {value:.4f}")
# Out:
# WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
#  1/12 [=>............................] - ETA: 32s - loss: 0.0000e+00 - accuracy: 0.9490
#  3/12 [======>.......................] - ETA: 0s - loss: 0.0000e+00 - accuracy: 0.9473
#  5/12 [===========>..................] - ETA: 0s - loss: 0.0000e+00 - accuracy: 0.9438
#  7/12 [================>.............] - ETA: 0s - loss: 0.0000e+00 - accuracy: 0.9416
#  9/12 [=====================>........] - ETA: 0s - loss: 0.0000e+00 - accuracy: 0.9392
# 11/12 [==========================>...] - ETA: 0s - loss: 0.0000e+00 - accuracy: 0.9385
# 12/12 [==============================] - 3s 25ms/step - loss: 0.0000e+00 - accuracy: 0.9388
# loss: 0.0000
# accuracy: 0.9388

# %%
# Model Summary
model.summary()
# Out:
# Model: "random_forest_model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
# =================================================================
# Total params: 1 (1.00 Byte)
# Trainable params: 0 (0.00 Byte)
# Non-trainable params: 1 (1.00 Byte)
# _________________________________________________________________
# Type: "RANDOM_FOREST"
# Task: CLASSIFICATION
# Label: "__LABEL"
#
# Input Features (18):
# 	10Percentile
# 	90Percentile
# 	Energy
# 	Entropy
# 	InterquartileRange
# 	Kurtosis
# 	Maximum
# 	Mean
# 	MeanAbsoluteDeviation
# 	Median
# 	Minimum
# 	Range
# 	RobustMeanAbsoluteDeviation
# 	RootMeanSquared
# 	Skewness
# 	TotalEnergy
# 	Uniformity
# 	Variance
#
# Trained with weights
#
# Variable Importance: INV_MEAN_MIN_DEPTH:
#     1.                "90Percentile"  0.135039 ################
#     2.                 "TotalEnergy"  0.132725 ###############
#     3.                     "Maximum"  0.130490 ##############
#     4.             "RootMeanSquared"  0.128477 #############
#     5.                      "Energy"  0.127643 #############
#     6.                       "Range"  0.123208 ############
#     7.                     "Minimum"  0.119971 ###########
#     8.                        "Mean"  0.110331 #######
#     9.                      "Median"  0.103080 #####
#    10.                    "Kurtosis"  0.100391 ####
#    11.                    "Skewness"  0.094785 ##
#    12.                "10Percentile"  0.092662 #
#    13.          "InterquartileRange"  0.092329 #
#    14.                  "Uniformity"  0.090413 #
#    15. "RobustMeanAbsoluteDeviation"  0.089090
#    16.                    "Variance"  0.088630
#    17.                     "Entropy"  0.087001
#    18.       "MeanAbsoluteDeviation"  0.086694
#
# Variable Importance: NUM_AS_ROOT:
#     1.     "TotalEnergy" 75.000000 ################
#     2. "RootMeanSquared" 69.000000 ##############
#     3.          "Energy" 66.000000 ##############
#     4.    "90Percentile" 27.000000 #####
#     5.            "Mean" 26.000000 #####
#     6.          "Median" 17.000000 ###
#     7.         "Maximum" 10.000000 #
#     8.    "10Percentile"  6.000000 #
#     9.         "Minimum"  3.000000
#    10.      "Uniformity"  1.000000
#
# Variable Importance: NUM_NODES:
#     1.                    "Skewness" 24690.000000 ################
#     2.                     "Maximum" 24138.000000 ###############
#     3.                       "Range" 23573.000000 ##############
#     4.                    "Kurtosis" 22050.000000 ############
#     5.                  "Uniformity" 20767.000000 ##########
#     6.                      "Median" 20479.000000 #########
#     7.                "90Percentile" 20179.000000 #########
#     8.                     "Entropy" 19657.000000 ########
#     9.                     "Minimum" 18824.000000 #######
#    10.                    "Variance" 18579.000000 #######
#    11. "RobustMeanAbsoluteDeviation" 18364.000000 ######
#    12.          "InterquartileRange" 18282.000000 ######
#    13.       "MeanAbsoluteDeviation" 17536.000000 #####
#    14.                "10Percentile" 17194.000000 #####
#    15.                        "Mean" 15981.000000 ###
#    16.             "RootMeanSquared" 13748.000000
#    17.                 "TotalEnergy" 13651.000000
#    18.                      "Energy" 13635.000000
#
# Variable Importance: SUM_SCORE:
#     1.                 "TotalEnergy" 1470198.561556 ################
#     2.             "RootMeanSquared" 1393841.475268 ##############
#     3.                      "Energy" 1358405.234067 ##############
#     4.                "90Percentile" 1182802.430867 ###########
#     5.                     "Maximum" 998575.140643 #########
#     6.                        "Mean" 896538.997395 #######
#     7.                       "Range" 772405.160748 #####
#     8.                      "Median" 744308.393402 #####
#     9.                     "Minimum" 742058.937671 #####
#    10.                    "Kurtosis" 558018.966587 ##
#    11.                    "Skewness" 536854.665419 ##
#    12.                "10Percentile" 448280.091691 #
#    13.                  "Uniformity" 412757.551855
#    14.          "InterquartileRange" 398493.428000
#    15. "RobustMeanAbsoluteDeviation" 390852.497029
#    16.                    "Variance" 389545.818997
#    17.                     "Entropy" 382612.547434
#    18.       "MeanAbsoluteDeviation" 360218.795903
#
#
#
# Winner takes all: true
# Out-of-bag evaluation: accuracy:0.833784 logloss:0.565509
# Number of trees: 300
# Total number of nodes: 682954
#
# Number of nodes by tree:
# Count: 300 Average: 2276.51 StdDev: 105.139
# Min: 1963 Max: 2507 Ignored: 0
# ----------------------------------------------
# [ 1963, 1990)  3   1.00%   1.00% #
# [ 1990, 2017)  2   0.67%   1.67% #
# [ 2017, 2044)  3   1.00%   2.67% #
# [ 2044, 2072)  1   0.33%   3.00%
# [ 2072, 2099)  3   1.00%   4.00% #
# [ 2099, 2126)  8   2.67%   6.67% ###
# [ 2126, 2153)  9   3.00%   9.67% ###
# [ 2153, 2181) 23   7.67%  17.33% #######
# [ 2181, 2208) 28   9.33%  26.67% #########
# [ 2208, 2235) 25   8.33%  35.00% ########
# [ 2235, 2262) 32  10.67%  45.67% ##########
# [ 2262, 2290) 25   8.33%  54.00% ########
# [ 2290, 2317) 27   9.00%  63.00% ########
# [ 2317, 2344) 24   8.00%  71.00% ########
# [ 2344, 2371) 23   7.67%  78.67% #######
# [ 2371, 2399) 23   7.67%  86.33% #######
# [ 2399, 2426) 21   7.00%  93.33% #######
# [ 2426, 2453)  8   2.67%  96.00% ###
# [ 2453, 2480)  7   2.33%  98.33% ##
# [ 2480, 2507]  5   1.67% 100.00% ##
#
# Depth by leafs:
# Count: 341627 Average: 12.5084 StdDev: 2.33037
# Min: 3 Max: 15 Ignored: 0
# ----------------------------------------------
# [  3,  4)     2   0.00%   0.00%
# [  4,  5)   183   0.05%   0.05%
# [  5,  6)  1183   0.35%   0.40%
# [  6,  7)  3225   0.94%   1.34%
# [  7,  8)  6488   1.90%   3.24% #
# [  8,  9) 11919   3.49%   6.73% #
# [  9, 10) 18967   5.55%  12.28% ##
# [ 10, 11) 27356   8.01%  20.29% ###
# [ 11, 12) 35581  10.42%  30.71% ####
# [ 12, 13) 43468  12.72%  43.43% #####
# [ 13, 14) 49025  14.35%  57.78% #####
# [ 14, 15) 51622  15.11%  72.89% ######
# [ 15, 15] 92608  27.11% 100.00% ##########
#
# Number of training obs by leaf:
# Count: 341627 Average: 69.121 StdDev: 273.685
# Min: 5 Max: 11794 Ignored: 0
# ----------------------------------------------
# [     5,   594) 334706  97.97%  97.97% ##########
# [   594,  1184)   4109   1.20%  99.18%
# [  1184,  1773)   1090   0.32%  99.50%
# [  1773,  2363)    600   0.18%  99.67%
# [  2363,  2952)    334   0.10%  99.77%
# [  2952,  3542)    216   0.06%  99.83%
# [  3542,  4131)    195   0.06%  99.89%
# [  4131,  4721)    161   0.05%  99.94%
# [  4721,  5310)    127   0.04%  99.97%
# [  5310,  5900)     53   0.02%  99.99%
# [  5900,  6489)     21   0.01% 100.00%
# [  6489,  7079)      6   0.00% 100.00%
# [  7079,  7668)      4   0.00% 100.00%
# [  7668,  8258)      2   0.00% 100.00%
# [  8258,  8847)      0   0.00% 100.00%
# [  8847,  9437)      1   0.00% 100.00%
# [  9437, 10026)      0   0.00% 100.00%
# [ 10026, 10616)      0   0.00% 100.00%
# [ 10616, 11205)      1   0.00% 100.00%
# [ 11205, 11794]      1   0.00% 100.00%
#
# Attribute in nodes:
# 	24690 : Skewness [NUMERICAL]
# 	24138 : Maximum [NUMERICAL]
# 	23573 : Range [NUMERICAL]
# 	22050 : Kurtosis [NUMERICAL]
# 	20767 : Uniformity [NUMERICAL]
# 	20479 : Median [NUMERICAL]
# 	20179 : 90Percentile [NUMERICAL]
# 	19657 : Entropy [NUMERICAL]
# 	18824 : Minimum [NUMERICAL]
# 	18579 : Variance [NUMERICAL]
# 	18364 : RobustMeanAbsoluteDeviation [NUMERICAL]
# 	18282 : InterquartileRange [NUMERICAL]
# 	17536 : MeanAbsoluteDeviation [NUMERICAL]
# 	17194 : 10Percentile [NUMERICAL]
# 	15981 : Mean [NUMERICAL]
# 	13748 : RootMeanSquared [NUMERICAL]
# 	13651 : TotalEnergy [NUMERICAL]
# 	13635 : Energy [NUMERICAL]
#
# Attribute in nodes with depth <= 0:
# 	75 : TotalEnergy [NUMERICAL]
# 	69 : RootMeanSquared [NUMERICAL]
# 	66 : Energy [NUMERICAL]
# 	27 : 90Percentile [NUMERICAL]
# 	26 : Mean [NUMERICAL]
# 	17 : Median [NUMERICAL]
# 	10 : Maximum [NUMERICAL]
# 	6 : 10Percentile [NUMERICAL]
# 	3 : Minimum [NUMERICAL]
# 	1 : Uniformity [NUMERICAL]
#
# Attribute in nodes with depth <= 1:
# 	152 : RootMeanSquared [NUMERICAL]
# 	151 : TotalEnergy [NUMERICAL]
# 	148 : Energy [NUMERICAL]
# 	98 : Maximum [NUMERICAL]
# 	92 : 90Percentile [NUMERICAL]
# 	79 : Range [NUMERICAL]
# 	61 : Mean [NUMERICAL]
# 	48 : Median [NUMERICAL]
# 	29 : Minimum [NUMERICAL]
# 	19 : Variance [NUMERICAL]
# 	13 : 10Percentile [NUMERICAL]
# 	5 : Entropy [NUMERICAL]
# 	3 : MeanAbsoluteDeviation [NUMERICAL]
# 	1 : Uniformity [NUMERICAL]
# 	1 : InterquartileRange [NUMERICAL]
#
# Attribute in nodes with depth <= 2:
# 	307 : TotalEnergy [NUMERICAL]
# 	296 : RootMeanSquared [NUMERICAL]
# 	296 : Energy [NUMERICAL]
# 	258 : 90Percentile [NUMERICAL]
# 	237 : Mean [NUMERICAL]
# 	195 : Median [NUMERICAL]
# 	144 : Maximum [NUMERICAL]
# 	93 : Range [NUMERICAL]
# 	77 : Minimum [NUMERICAL]
# 	40 : InterquartileRange [NUMERICAL]
# 	32 : 10Percentile [NUMERICAL]
# 	28 : Uniformity [NUMERICAL]
# 	21 : Skewness [NUMERICAL]
# 	21 : Kurtosis [NUMERICAL]
# 	19 : Variance [NUMERICAL]
# 	19 : Entropy [NUMERICAL]
# 	13 : RobustMeanAbsoluteDeviation [NUMERICAL]
# 	4 : MeanAbsoluteDeviation [NUMERICAL]
#
# Attribute in nodes with depth <= 3:
# 	486 : 90Percentile [NUMERICAL]
# 	418 : TotalEnergy [NUMERICAL]
# 	418 : RootMeanSquared [NUMERICAL]
# 	405 : Energy [NUMERICAL]
# 	399 : Mean [NUMERICAL]
# 	342 : Maximum [NUMERICAL]
# 	331 : Median [NUMERICAL]
# 	293 : Minimum [NUMERICAL]
# 	283 : Range [NUMERICAL]
# 	187 : InterquartileRange [NUMERICAL]
# 	181 : Kurtosis [NUMERICAL]
# 	176 : Uniformity [NUMERICAL]
# 	152 : Skewness [NUMERICAL]
# 	145 : 10Percentile [NUMERICAL]
# 	92 : RobustMeanAbsoluteDeviation [NUMERICAL]
# 	86 : Entropy [NUMERICAL]
# 	53 : Variance [NUMERICAL]
# 	51 : MeanAbsoluteDeviation [NUMERICAL]
#
# Attribute in nodes with depth <= 5:
# 	1341 : Maximum [NUMERICAL]
# 	1276 : 90Percentile [NUMERICAL]
# 	1244 : Range [NUMERICAL]
# 	1174 : Skewness [NUMERICAL]
# 	1163 : Median [NUMERICAL]
# 	1125 : Minimum [NUMERICAL]
# 	1086 : Kurtosis [NUMERICAL]
# 	971 : Mean [NUMERICAL]
# 	948 : Uniformity [NUMERICAL]
# 	945 : InterquartileRange [NUMERICAL]
# 	916 : RootMeanSquared [NUMERICAL]
# 	900 : TotalEnergy [NUMERICAL]
# 	878 : Energy [NUMERICAL]
# 	725 : 10Percentile [NUMERICAL]
# 	698 : RobustMeanAbsoluteDeviation [NUMERICAL]
# 	634 : Entropy [NUMERICAL]
# 	596 : MeanAbsoluteDeviation [NUMERICAL]
# 	534 : Variance [NUMERICAL]
#
# Condition type in nodes:
# 	341327 : HigherCondition
# Condition type in nodes with depth <= 0:
# 	300 : HigherCondition
# Condition type in nodes with depth <= 1:
# 	900 : HigherCondition
# Condition type in nodes with depth <= 2:
# 	2100 : HigherCondition
# Condition type in nodes with depth <= 3:
# 	4498 : HigherCondition
# Condition type in nodes with depth <= 5:
# 	17154 : HigherCondition
# Node format: NOT_SET
#
# Training OOB:
# 	trees: 1, Out-of-bag evaluation: accuracy:0.807878 logloss:6.92477
# 	trees: 11, Out-of-bag evaluation: accuracy:0.808711 logloss:3.30517
# 	trees: 21, Out-of-bag evaluation: accuracy:0.820411 logloss:1.92043
# 	trees: 31, Out-of-bag evaluation: accuracy:0.823067 logloss:1.50838
# 	trees: 41, Out-of-bag evaluation: accuracy:0.823408 logloss:1.27
# 	trees: 51, Out-of-bag evaluation: accuracy:0.826868 logloss:1.139
# 	trees: 61, Out-of-bag evaluation: accuracy:0.828587 logloss:1.06324
# 	trees: 71, Out-of-bag evaluation: accuracy:0.828745 logloss:0.996113
# 	trees: 81, Out-of-bag evaluation: accuracy:0.829879 logloss:0.932476
# 	trees: 91, Out-of-bag evaluation: accuracy:0.830878 logloss:0.884673
# 	trees: 101, Out-of-bag evaluation: accuracy:0.831081 logloss:0.842651
# 	trees: 111, Out-of-bag evaluation: accuracy:0.829687 logloss:0.812377
# 	trees: 121, Out-of-bag evaluation: accuracy:0.830435 logloss:0.791442
# 	trees: 131, Out-of-bag evaluation: accuracy:0.831664 logloss:0.768215
# 	trees: 141, Out-of-bag evaluation: accuracy:0.832216 logloss:0.746037
# 	trees: 151, Out-of-bag evaluation: accuracy:0.832643 logloss:0.73456
# 	trees: 161, Out-of-bag evaluation: accuracy:0.832434 logloss:0.711698
# 	trees: 171, Out-of-bag evaluation: accuracy:0.832291 logloss:0.697481
# 	trees: 181, Out-of-bag evaluation: accuracy:0.832902 logloss:0.674162
# 	trees: 191, Out-of-bag evaluation: accuracy:0.832821 logloss:0.657051
# 	trees: 201, Out-of-bag evaluation: accuracy:0.832998 logloss:0.648478
# 	trees: 211, Out-of-bag evaluation: accuracy:0.8339 logloss:0.631222
# 	trees: 221, Out-of-bag evaluation: accuracy:0.833907 logloss:0.611315
# 	trees: 231, Out-of-bag evaluation: accuracy:0.833737 logloss:0.605606
# 	trees: 241, Out-of-bag evaluation: accuracy:0.832929 logloss:0.597096
# 	trees: 251, Out-of-bag evaluation: accuracy:0.833302 logloss:0.594033
# 	trees: 261, Out-of-bag evaluation: accuracy:0.832738 logloss:0.58531
# 	trees: 271, Out-of-bag evaluation: accuracy:0.832595 logloss:0.582177
# 	trees: 281, Out-of-bag evaluation: accuracy:0.833091 logloss:0.576581
# 	trees: 291, Out-of-bag evaluation: accuracy:0.833743 logloss:0.571163
# 	trees: 300, Out-of-bag evaluation: accuracy:0.833784 logloss:0.565509

# %%
# Model features
model.make_inspector().features()
# Out:
# ["10Percentile" (1; #0),
#  "90Percentile" (1; #1),
#  "Energy" (1; #2),
#  "Entropy" (1; #3),
#  "InterquartileRange" (1; #4),
#  "Kurtosis" (1; #5),
#  "Maximum" (1; #6),
#  "Mean" (1; #7),
#  "MeanAbsoluteDeviation" (1; #8),
#  "Median" (1; #9),
#  "Minimum" (1; #10),
#  "Range" (1; #11),
#  "RobustMeanAbsoluteDeviation" (1; #12),
#  "RootMeanSquared" (1; #13),
#  "Skewness" (1; #14),
#  "TotalEnergy" (1; #15),
#  "Uniformity" (1; #16),
#  "Variance" (1; #17)]

# %%
# Feature importance
model.make_inspector().variable_importances()
# Out:
# {'INV_MEAN_MIN_DEPTH': [("90Percentile" (1; #1), 0.1350385624627972),
#   ("TotalEnergy" (1; #15), 0.13272492800890195),
#   ("Maximum" (1; #6), 0.130490225567832),
#   ("RootMeanSquared" (1; #13), 0.12847727337630185),
#   ("Energy" (1; #2), 0.12764342244250548),
#   ("Range" (1; #11), 0.1232083445080157),
#   ("Minimum" (1; #10), 0.11997146158654726),
#   ("Mean" (1; #7), 0.11033147397154575),
#   ("Median" (1; #9), 0.10308041165584521),
#   ("Kurtosis" (1; #5), 0.10039147028407548),
#   ("Skewness" (1; #14), 0.09478495978482783),
#   ("10Percentile" (1; #0), 0.09266231043512041),
#   ("InterquartileRange" (1; #4), 0.09232913448267271),
#   ("Uniformity" (1; #16), 0.09041281617960015),
#   ("RobustMeanAbsoluteDeviation" (1; #12), 0.08909007081545402),
#   ("Variance" (1; #17), 0.08863020853230612),
#   ("Entropy" (1; #3), 0.08700140922823114),
#   ("MeanAbsoluteDeviation" (1; #8), 0.08669391403490787)],
#  'NUM_AS_ROOT': [("TotalEnergy" (1; #15), 75.0),
#   ("RootMeanSquared" (1; #13), 69.0),
#   ("Energy" (1; #2), 66.0),
#   ("90Percentile" (1; #1), 27.0),
#   ("Mean" (1; #7), 26.0),
#   ("Median" (1; #9), 17.0),
#   ("Maximum" (1; #6), 10.0),
#   ("10Percentile" (1; #0), 6.0),
#   ("Minimum" (1; #10), 3.0),
#   ("Uniformity" (1; #16), 1.0)],
#  'SUM_SCORE': [("TotalEnergy" (1; #15), 1470198.561555742),
#   ("RootMeanSquared" (1; #13), 1393841.475267678),
#   ("Energy" (1; #2), 1358405.234067249),
#   ("90Percentile" (1; #1), 1182802.4308667255),
#   ("Maximum" (1; #6), 998575.140643242),
#   ("Mean" (1; #7), 896538.9973950994),
#   ("Range" (1; #11), 772405.160748078),
#   ("Median" (1; #9), 744308.3934015877),
#   ("Minimum" (1; #10), 742058.9376709433),
#   ("Kurtosis" (1; #5), 558018.9665869325),
#   ("Skewness" (1; #14), 536854.665418926),
#   ("10Percentile" (1; #0), 448280.09169081436),
#   ("Uniformity" (1; #16), 412757.5518546253),
#   ("InterquartileRange" (1; #4), 398493.4280004223),
#   ("RobustMeanAbsoluteDeviation" (1; #12), 390852.49702907534),
#   ("Variance" (1; #17), 389545.81899697613),
#   ("Entropy" (1; #3), 382612.5474340841),
#   ("MeanAbsoluteDeviation" (1; #8), 360218.79590268136)],
#  'NUM_NODES': [("Skewness" (1; #14), 24690.0),
#   ("Maximum" (1; #6), 24138.0),
#   ("Range" (1; #11), 23573.0),
#   ("Kurtosis" (1; #5), 22050.0),
#   ("Uniformity" (1; #16), 20767.0),
#   ("Median" (1; #9), 20479.0),
#   ("90Percentile" (1; #1), 20179.0),
#   ("Entropy" (1; #3), 19657.0),
#   ("Minimum" (1; #10), 18824.0),
#   ("Variance" (1; #17), 18579.0),
#   ("RobustMeanAbsoluteDeviation" (1; #12), 18364.0),
#   ("InterquartileRange" (1; #4), 18282.0),
#   ("MeanAbsoluteDeviation" (1; #8), 17536.0),
#   ("10Percentile" (1; #0), 17194.0),
#   ("Mean" (1; #7), 15981.0),
#   ("RootMeanSquared" (1; #13), 13748.0),
#   ("TotalEnergy" (1; #15), 13651.0),
#   ("Energy" (1; #2), 13635.0)]}

# %%
# Model self evaluation
model.make_inspector().evaluation()
# Out:
# Evaluation(num_examples=78712, accuracy=0.833784006251315, loss=0.565508575485314, rmse=None, ndcg=None, aucs=None, auuc=None, qini=None)

# %%
logs = model.make_inspector().training_logs()

plt.figure(figsize=(12, 4))
plt.subplot(1, 2, 1)
plt.plot([log.num_trees for log in logs], [log.evaluation.accuracy for log in logs])
plt.xlabel("Number of trees")
plt.ylabel("Accuracy (out-of-bag)")
plt.subplot(1, 2, 2)
plt.plot([log.num_trees for log in logs], [log.evaluation.loss for log in logs])
plt.xlabel("Number of trees")
plt.ylabel("Logloss (out-of-bag)")
plt.show()

# %% [markdown]
# Calculate the score of our hold-out validation dataset

# %%
predictions = model.predict(val_ds)
y_true      = validation_data["label"]

from sklearn.metrics import roc_auc_score
ROC_AUC = roc_auc_score(y_true, predictions)
print("The ROC AUC score is %.5f" % ROC_AUC )
# Out:
#  1/12 [=>............................] - ETA: 0s
#  3/12 [======>.......................] - ETA: 0s
#  5/12 [===========>..................] - ETA: 0s
#  7/12 [================>.............] - ETA: 0s
# 10/12 [========================>.....] - ETA: 0s
# 12/12 [==============================] - 0s 24ms/step
# The ROC AUC score is 0.93641

# %%
# Compute binary classification metrics with sklearn
import numpy as np
from sklearn.metrics import (
    accuracy_score,
    precision_score,
    recall_score,
    f1_score,
    roc_auc_score,
    average_precision_score,
    confusion_matrix,
    classification_report,
    matthews_corrcoef,
    log_loss,
    brier_score_loss,
)

# Get predictions (probabilities or class labels)
preds = model.predict(test_ds)
# If model outputs probabilities, convert to labels by threshold 0.5
if preds.ndim == 2:
    # For TFDF classification, preds may be class probabilities with shape (N, 2)
    if preds.shape[1] == 2:
        pos_probs = preds[:, 1]
    else:
        # If single-probability column (positive class)
        pos_probs = preds[:, -1]
    y_pred = (pos_probs >= 0.5).astype(int)
else:
    # Already class labels
    y_pred = preds.astype(int)
    pos_probs = None

# Ground truth labels (must be 0/1 integers)
y_true = test_data["label"].astype(int).to_numpy()

# Core metrics
metrics = {}
metrics["accuracy"] = accuracy_score(y_true, y_pred)
metrics["precision"] = precision_score(y_true, y_pred, zero_division=0)
metrics["recall"] = recall_score(y_true, y_pred, zero_division=0)
metrics["f1"] = f1_score(y_true, y_pred, zero_division=0)
metrics["mcc"] = matthews_corrcoef(y_true, y_pred)

# Probabilistic metrics (only if we have probabilities)
if pos_probs is not None:
    metrics["roc_auc"] = roc_auc_score(y_true, pos_probs)
    metrics["pr_auc"] = average_precision_score(y_true, pos_probs)
    metrics["log_loss"] = log_loss(y_true, pos_probs, labels=[0,1])
    metrics["brier_score"] = brier_score_loss(y_true, pos_probs)

# Confusion matrix and detailed report
cm = confusion_matrix(y_true, y_pred, labels=[0,1])
report = classification_report(y_true, y_pred, digits=4)

print("Sklearn binary metrics:")
for k, v in metrics.items():
    print(f"{k}: {v:.4f}")
print("\nConfusion matrix:\n", cm)
print("\nClassification report:\n", report)
# Out:
#  1/23 [>.............................] - ETA: 1s
#  3/23 [==>...........................] - ETA: 0s
#  5/23 [=====>........................] - ETA: 0s
#  7/23 [========>.....................] - ETA: 0s
# 10/23 [============>.................] - ETA: 0s
# 12/23 [==============>...............] - ETA: 0s
# 14/23 [=================>............] - ETA: 0s
# 16/23 [===================>..........] - ETA: 0s
# 18/23 [======================>.......] - ETA: 0s
# 21/23 [==========================>...] - ETA: 0s
# 23/23 [==============================] - 1s 26ms/step
# Sklearn binary metrics:
# accuracy: 0.9401
# precision: 0.5684
# recall: 0.7174
# f1: 0.6343
# mcc: 0.6070
# roc_auc: 0.9379
# pr_auc: 0.7293
# log_loss: 0.1672
# brier_score: 0.0468
#
# Confusion matrix:
#  [[19975   887]
#  [  460  1168]]
#
# Classification report:
#                precision    recall  f1-score   support
#
#            0     0.9775    0.9575    0.9674     20862
#            1     0.5684    0.7174    0.6343      1628
#
#     accuracy                         0.9401     22490
#    macro avg     0.7729    0.8375    0.8008     22490
# weighted avg     0.9479    0.9401    0.9433     22490
