# %%
# Import packages and modules
import numpy  as np
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow_decision_forests as tfdf

from sklearn.model_selection import train_test_split
# Out:
# 2026-08-10 17:10:16.666294: I tensorflow/core/util/port.cc:113] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2026-08-10 17:10:17.106907: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2026-08-10 17:10:21.651413: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
# Check the version of TensorFlow Decision Forests
print("Found TensorFlow Decision Forests v" + tfdf.__version__)
# Out:
# Found TensorFlow Decision Forests v1.9.1

# %%
datasetPath = 'dataset/firstorder/kernel5-radius5/dataset.csv'

# %%
# Parameters
datasetPath = "dataset/firstorder/kernel4-radius4/dataset.1p.csv"

# %%
# train/validation/test = 70/10/20
dataset = pd.read_csv(datasetPath)

train_data, temp_data = train_test_split(dataset, test_size=0.3, random_state=42)
validation_data, test_data = train_test_split(temp_data, test_size=2/3, random_state=42)

# %%
from sklearn.utils.class_weight import compute_class_weight

# tinh class weight tren tap train
classes = np.array([0, 1])
weights = compute_class_weight(class_weight="balanced", classes=classes, y=train_data["label"])
class_weight = {0: weights[0], 1: weights[1]}

# gan sample_weight cho tung dong
train_data["sample_weight"] = train_data["label"].map(class_weight)
validation_data["sample_weight"] = validation_data["label"].map(class_weight)
test_data["sample_weight"] = test_data["label"].map(class_weight)

# Convert the dataset into a TensorFlow dataset.
train_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    train_data, label="label", weight="sample_weight"
)         
val_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    validation_data, label="label", weight="sample_weight"
)
test_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    test_data, label="label", weight="sample_weight"
)
# Out:
# 2026-08-10 17:10:34.733924: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:984] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2026-08-10 17:10:34.735204: W tensorflow/core/common_runtime/gpu/gpu_device.cc:2251] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...

# %%
import keras

# %%
# %%time

# Train a Gradient Boosted Trees model.
model = tfdf.keras.GradientBoostedTreesModel()

# Add evaluation metrics
model.compile(
    metrics=["accuracy"]
)
model.fit(x=train_ds)

# # Train a Gradient Boosted Trees model.
# model = tfdf.keras.GradientBoostedTreesModel(num_trees=1500)
# model.fit(train_ds)
# Out:
# Use /tmp/tmp7uq6075m as temporary training directory
# Reading training dataset...
# [WARNING 26-08-10 17:10:34.8799 UTC gradient_boosted_trees.cc:1840] "goss_alpha" set but "sampling_method" not equal to "GOSS".
# [WARNING 26-08-10 17:10:34.8801 UTC gradient_boosted_trees.cc:1851] "goss_beta" set but "sampling_method" not equal to "GOSS".
# [WARNING 26-08-10 17:10:34.8801 UTC gradient_boosted_trees.cc:1865] "selective_gradient_boosting_ratio" set but "sampling_method" not equal to "SELGB".
# Training dataset read in 0:00:02.414112. Found 1542 examples.
# Training model...
# Model trained in 0:00:00.366758
# Compiling model...
# [INFO 26-08-10 17:10:37.6852 UTC kernel.cc:1233] Loading model from path /tmp/tmp7uq6075m/model/ with prefix 57729cafca0d41b8
# [INFO 26-08-10 17:10:37.6879 UTC quick_scorer_extended.cc:911] The binary was compiled without AVX2 support, but your CPU supports it. Enable it for faster model inference.
# [INFO 26-08-10 17:10:37.6881 UTC abstract_model.cc:1362] Engine "GradientBoostedTreesQuickScorerExtended" built
# [INFO 26-08-10 17:10:37.6881 UTC kernel.cc:1061] Use fast generic engine
# Model compiled.
# CPU times: user 5.68 s, sys: 538 ms, total: 6.22 s
# Wall time: 7.58 s

# %%
# Evaluate the model
evaluate = model.evaluate(val_ds, return_dict=True)
print()

for name, value in evaluate.items():
    print(f"{name}: {value:.4f}")
# Out:
# WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 1/1 [==============================] - ETA: 0s - loss: 0.0000e+00 - accuracy: 1.0000
# 1/1 [==============================] - 3s 3s/step - loss: 0.0000e+00 - accuracy: 1.0000
# loss: 0.0000
# accuracy: 1.0000

# %%
# Model Summary
model.summary()
# Out:
# Model: "gradient_boosted_trees_model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
# =================================================================
# Total params: 1 (1.00 Byte)
# Trainable params: 0 (0.00 Byte)
# Non-trainable params: 1 (1.00 Byte)
# _________________________________________________________________
# Type: "GRADIENT_BOOSTED_TREES"
# Task: CLASSIFICATION
# Label: "__LABEL"
#
# Input Features (18):
# 	10Percentile
# 	90Percentile
# 	Energy
# 	Entropy
# 	InterquartileRange
# 	Kurtosis
# 	Maximum
# 	Mean
# 	MeanAbsoluteDeviation
# 	Median
# 	Minimum
# 	Range
# 	RobustMeanAbsoluteDeviation
# 	RootMeanSquared
# 	Skewness
# 	TotalEnergy
# 	Uniformity
# 	Variance
#
# Trained with weights
#
# Variable Importance: INV_MEAN_MIN_DEPTH:
#     1.             "RootMeanSquared"  0.417392 ################
#     2.                        "Mean"  0.303748 ########
#     3.                 "TotalEnergy"  0.249750 ####
#     4.                      "Energy"  0.245274 ####
#     5.                "10Percentile"  0.220864 ##
#     6.                      "Median"  0.215708 ##
#     7.                     "Minimum"  0.200568 #
#     8.                "90Percentile"  0.193374
#     9.                       "Range"  0.191354
#    10.                     "Maximum"  0.190595
#    11.       "MeanAbsoluteDeviation"  0.190512
#    12.                    "Skewness"  0.188015
#    13.          "InterquartileRange"  0.187587
#    14. "RobustMeanAbsoluteDeviation"  0.186931
#    15.                    "Variance"  0.186164
#    16.                    "Kurtosis"  0.184597
#    17.                     "Entropy"  0.184424
#    18.                  "Uniformity"  0.184154
#
# Variable Importance: NUM_AS_ROOT:
#     1. "RootMeanSquared" 29.000000 ################
#     2.            "Mean" 15.000000
#
# Variable Importance: NUM_NODES:
#     1.                        "Mean" 134.000000 ################
#     2.                 "TotalEnergy" 94.000000 ###########
#     3.             "RootMeanSquared" 86.000000 ##########
#     4.                      "Energy" 83.000000 #########
#     5.                      "Median" 59.000000 ######
#     6.                "10Percentile" 55.000000 ######
#     7.                     "Minimum" 44.000000 ####
#     8.       "MeanAbsoluteDeviation" 40.000000 ####
#     9.                     "Maximum" 39.000000 ####
#    10.                "90Percentile" 33.000000 ###
#    11.                       "Range" 27.000000 ##
#    12.                    "Skewness" 27.000000 ##
#    13.                    "Variance" 23.000000 ##
#    14. "RobustMeanAbsoluteDeviation" 18.000000 #
#    15.          "InterquartileRange" 14.000000 #
#    16.                    "Kurtosis" 10.000000
#    17.                     "Entropy"  8.000000
#    18.                  "Uniformity"  6.000000
#
# Variable Importance: SUM_SCORE:
#     1.                        "Mean" 1303.012143 ################
#     2.             "RootMeanSquared" 186.038312 ##
#     3.                 "TotalEnergy" 168.287513 ##
#     4.                      "Energy" 113.932329 #
#     5.                "10Percentile" 77.180810
#     6.                      "Median" 11.336899
#     7.                     "Minimum"  9.079292
#     8.                "90Percentile"  6.064637
#     9.          "InterquartileRange"  2.577883
#    10.                     "Entropy"  0.505493
#    11.       "MeanAbsoluteDeviation"  0.449464
#    12.                    "Skewness"  0.319686
#    13. "RobustMeanAbsoluteDeviation"  0.194684
#    14.                    "Variance"  0.129335
#    15.                       "Range"  0.123690
#    16.                  "Uniformity"  0.100188
#    17.                    "Kurtosis"  0.016647
#    18.                     "Maximum"  0.010653
#
#
#
# Loss: BINOMIAL_LOG_LIKELIHOOD
# Validation loss value: 0.0588314
# Number of trees per iteration: 1
# Node format: NOT_SET
# Number of trees: 44
# Total number of nodes: 1644
#
# Number of nodes by tree:
# Count: 44 Average: 37.3636 StdDev: 2.96258
# Min: 31 Max: 43 Ignored: 0
# ----------------------------------------------
# [ 31, 32)  1   2.27%   2.27% #
# [ 32, 33)  0   0.00%   2.27%
# [ 33, 34)  5  11.36%  13.64% ####
# [ 34, 35)  0   0.00%  13.64%
# [ 35, 36)  9  20.45%  34.09% ########
# [ 36, 37)  0   0.00%  34.09%
# [ 37, 38) 10  22.73%  56.82% ########
# [ 38, 39)  0   0.00%  56.82%
# [ 39, 40) 12  27.27%  84.09% ##########
# [ 40, 41)  0   0.00%  84.09%
# [ 41, 42)  3   6.82%  90.91% ###
# [ 42, 43)  0   0.00%  90.91%
# [ 43, 43]  4   9.09% 100.00% ###
#
# Depth by leafs:
# Count: 844 Average: 4.45024 StdDev: 0.696053
# Min: 3 Max: 5 Ignored: 0
# ----------------------------------------------
# [ 3, 4) 100  11.85%  11.85% ##
# [ 4, 5) 264  31.28%  43.13% ######
# [ 5, 5] 480  56.87% 100.00% ##########
#
# Number of training obs by leaf:
# Count: 844 Average: 73.8199 StdDev: 157.339
# Min: 5 Max: 698 Ignored: 0
# ----------------------------------------------
# [   5,  39) 585  69.31%  69.31% ##########
# [  39,  74)  68   8.06%  77.37% #
# [  74, 109)  58   6.87%  84.24% #
# [ 109, 143)   1   0.12%  84.36%
# [ 143, 178)   9   1.07%  85.43%
# [ 178, 213)  56   6.64%  92.06% #
# [ 213, 247)  23   2.73%  94.79%
# [ 247, 282)   0   0.00%  94.79%
# [ 282, 317)   0   0.00%  94.79%
# [ 317, 352)   0   0.00%  94.79%
# [ 352, 386)   0   0.00%  94.79%
# [ 386, 421)   0   0.00%  94.79%
# [ 421, 456)   0   0.00%  94.79%
# [ 456, 490)   0   0.00%  94.79%
# [ 490, 525)   1   0.12%  94.91%
# [ 525, 560)   0   0.00%  94.91%
# [ 560, 594)   0   0.00%  94.91%
# [ 594, 629)   0   0.00%  94.91%
# [ 629, 664)   0   0.00%  94.91%
# [ 664, 698]  43   5.09% 100.00% #
#
# Attribute in nodes:
# 	134 : Mean [NUMERICAL]
# 	94 : TotalEnergy [NUMERICAL]
# 	86 : RootMeanSquared [NUMERICAL]
# 	83 : Energy [NUMERICAL]
# 	59 : Median [NUMERICAL]
# 	55 : 10Percentile [NUMERICAL]
# 	44 : Minimum [NUMERICAL]
# 	40 : MeanAbsoluteDeviation [NUMERICAL]
# 	39 : Maximum [NUMERICAL]
# 	33 : 90Percentile [NUMERICAL]
# 	27 : Skewness [NUMERICAL]
# 	27 : Range [NUMERICAL]
# 	23 : Variance [NUMERICAL]
# 	18 : RobustMeanAbsoluteDeviation [NUMERICAL]
# 	14 : InterquartileRange [NUMERICAL]
# 	10 : Kurtosis [NUMERICAL]
# 	8 : Entropy [NUMERICAL]
# 	6 : Uniformity [NUMERICAL]
#
# Attribute in nodes with depth <= 0:
# 	29 : RootMeanSquared [NUMERICAL]
# 	15 : Mean [NUMERICAL]
#
# Attribute in nodes with depth <= 1:
# 	32 : Energy [NUMERICAL]
# 	29 : RootMeanSquared [NUMERICAL]
# 	28 : TotalEnergy [NUMERICAL]
# 	15 : Mean [NUMERICAL]
# 	15 : 10Percentile [NUMERICAL]
# 	13 : Median [NUMERICAL]
#
# Attribute in nodes with depth <= 2:
# 	69 : RootMeanSquared [NUMERICAL]
# 	49 : TotalEnergy [NUMERICAL]
# 	48 : Mean [NUMERICAL]
# 	40 : Energy [NUMERICAL]
# 	21 : 90Percentile [NUMERICAL]
# 	17 : Median [NUMERICAL]
# 	17 : 10Percentile [NUMERICAL]
# 	15 : Range [NUMERICAL]
# 	15 : Minimum [NUMERICAL]
# 	7 : MeanAbsoluteDeviation [NUMERICAL]
# 	5 : InterquartileRange [NUMERICAL]
# 	3 : RobustMeanAbsoluteDeviation [NUMERICAL]
# 	2 : Variance [NUMERICAL]
#
# Attribute in nodes with depth <= 3:
# 	89 : Mean [NUMERICAL]
# 	79 : RootMeanSquared [NUMERICAL]
# 	74 : TotalEnergy [NUMERICAL]
# 	63 : Energy [NUMERICAL]
# 	46 : 10Percentile [NUMERICAL]
# 	32 : Median [NUMERICAL]
# 	31 : Maximum [NUMERICAL]
# 	30 : Minimum [NUMERICAL]
# 	26 : 90Percentile [NUMERICAL]
# 	20 : Range [NUMERICAL]
# 	19 : Skewness [NUMERICAL]
# 	13 : MeanAbsoluteDeviation [NUMERICAL]
# 	11 : RobustMeanAbsoluteDeviation [NUMERICAL]
# 	11 : InterquartileRange [NUMERICAL]
# 	7 : Entropy [NUMERICAL]
# 	5 : Variance [NUMERICAL]
# 	2 : Uniformity [NUMERICAL]
# 	2 : Kurtosis [NUMERICAL]
#
# Attribute in nodes with depth <= 5:
# 	134 : Mean [NUMERICAL]
# 	94 : TotalEnergy [NUMERICAL]
# 	86 : RootMeanSquared [NUMERICAL]
# 	83 : Energy [NUMERICAL]
# 	59 : Median [NUMERICAL]
# 	55 : 10Percentile [NUMERICAL]
# 	44 : Minimum [NUMERICAL]
# 	40 : MeanAbsoluteDeviation [NUMERICAL]
# 	39 : Maximum [NUMERICAL]
# 	33 : 90Percentile [NUMERICAL]
# 	27 : Skewness [NUMERICAL]
# 	27 : Range [NUMERICAL]
# 	23 : Variance [NUMERICAL]
# 	18 : RobustMeanAbsoluteDeviation [NUMERICAL]
# 	14 : InterquartileRange [NUMERICAL]
# 	10 : Kurtosis [NUMERICAL]
# 	8 : Entropy [NUMERICAL]
# 	6 : Uniformity [NUMERICAL]
#
# Condition type in nodes:
# 	800 : HigherCondition
# Condition type in nodes with depth <= 0:
# 	44 : HigherCondition
# Condition type in nodes with depth <= 1:
# 	132 : HigherCondition
# Condition type in nodes with depth <= 2:
# 	308 : HigherCondition
# Condition type in nodes with depth <= 3:
# 	560 : HigherCondition
# Condition type in nodes with depth <= 5:
# 	800 : HigherCondition
#
# Training logs:
# Number of iteration to final model: 44
# 	Iter:1 train-loss:1.198152 valid-loss:1.210389  train-accuracy:0.995730 valid-accuracy:0.986011
# 	Iter:2 train-loss:1.044063 valid-loss:1.058228  train-accuracy:0.997167 valid-accuracy:0.986011
# 	Iter:3 train-loss:0.915724 valid-loss:0.934806  train-accuracy:0.997167 valid-accuracy:0.986011
# 	Iter:4 train-loss:0.806998 valid-loss:0.827857  train-accuracy:0.997167 valid-accuracy:0.986011
# 	Iter:5 train-loss:0.714033 valid-loss:0.734173  train-accuracy:0.997167 valid-accuracy:0.986011
# 	Iter:6 train-loss:0.633907 valid-loss:0.657035  train-accuracy:0.997167 valid-accuracy:0.986011
# 	Iter:16 train-loss:0.213954 valid-loss:0.255405  train-accuracy:0.999042 valid-accuracy:0.986011
# 	Iter:26 train-loss:0.075616 valid-loss:0.112223  train-accuracy:1.000000 valid-accuracy:1.000000
# 	Iter:36 train-loss:0.027438 valid-loss:0.068438  train-accuracy:1.000000 valid-accuracy:0.986011
# 	Iter:46 train-loss:0.010041 valid-loss:0.061892  train-accuracy:1.000000 valid-accuracy:0.986011
# 	Iter:56 train-loss:0.003690 valid-loss:0.079381  train-accuracy:1.000000 valid-accuracy:0.986011
# 	Iter:66 train-loss:0.001357 valid-loss:0.112647  train-accuracy:1.000000 valid-accuracy:0.972023

# %%
# Model features
model.make_inspector().features()
# Out:
# ["10Percentile" (1; #0),
#  "90Percentile" (1; #1),
#  "Energy" (1; #2),
#  "Entropy" (1; #3),
#  "InterquartileRange" (1; #4),
#  "Kurtosis" (1; #5),
#  "Maximum" (1; #6),
#  "Mean" (1; #7),
#  "MeanAbsoluteDeviation" (1; #8),
#  "Median" (1; #9),
#  "Minimum" (1; #10),
#  "Range" (1; #11),
#  "RobustMeanAbsoluteDeviation" (1; #12),
#  "RootMeanSquared" (1; #13),
#  "Skewness" (1; #14),
#  "TotalEnergy" (1; #15),
#  "Uniformity" (1; #16),
#  "Variance" (1; #17)]

# %%
# Feature importance
model.make_inspector().variable_importances()
# Out:
# {'INV_MEAN_MIN_DEPTH': [("RootMeanSquared" (1; #13), 0.41739203356986165),
#   ("Mean" (1; #7), 0.3037477972834676),
#   ("TotalEnergy" (1; #15), 0.24975017866956284),
#   ("Energy" (1; #2), 0.24527358201421298),
#   ("10Percentile" (1; #0), 0.22086381216702153),
#   ("Median" (1; #9), 0.21570750612986514),
#   ("Minimum" (1; #10), 0.20056792507084967),
#   ("90Percentile" (1; #1), 0.19337401928570205),
#   ("Range" (1; #11), 0.1913544053209907),
#   ("Maximum" (1; #6), 0.19059489647710426),
#   ("MeanAbsoluteDeviation" (1; #8), 0.19051234823744478),
#   ("Skewness" (1; #14), 0.18801495375533375),
#   ("InterquartileRange" (1; #4), 0.18758739451554574),
#   ("RobustMeanAbsoluteDeviation" (1; #12), 0.18693078701985913),
#   ("Variance" (1; #17), 0.18616402700457085),
#   ("Kurtosis" (1; #5), 0.1845974941762592),
#   ("Entropy" (1; #3), 0.18442350924214865),
#   ("Uniformity" (1; #16), 0.18415389091658088)],
#  'NUM_AS_ROOT': [("RootMeanSquared" (1; #13), 29.0), ("Mean" (1; #7), 15.0)],
#  'SUM_SCORE': [("Mean" (1; #7), 1303.0121430102708),
#   ("RootMeanSquared" (1; #13), 186.03831150989154),
#   ("TotalEnergy" (1; #15), 168.28751277920296),
#   ("Energy" (1; #2), 113.9323288122039),
#   ("10Percentile" (1; #0), 77.18081009276412),
#   ("Median" (1; #9), 11.336899262000129),
#   ("Minimum" (1; #10), 9.079292395501414),
#   ("90Percentile" (1; #1), 6.0646367627722215),
#   ("InterquartileRange" (1; #4), 2.577883166156098),
#   ("Entropy" (1; #3), 0.5054927632131713),
#   ("MeanAbsoluteDeviation" (1; #8), 0.44946430557513334),
#   ("Skewness" (1; #14), 0.31968602785721145),
#   ("RobustMeanAbsoluteDeviation" (1; #12), 0.19468386399323745),
#   ("Variance" (1; #17), 0.12933454834862218),
#   ("Range" (1; #11), 0.12369018221829205),
#   ("Uniformity" (1; #16), 0.1001879245036586),
#   ("Kurtosis" (1; #5), 0.01664749127111376),
#   ("Maximum" (1; #6), 0.01065272297853403)],
#  'NUM_NODES': [("Mean" (1; #7), 134.0),
#   ("TotalEnergy" (1; #15), 94.0),
#   ("RootMeanSquared" (1; #13), 86.0),
#   ("Energy" (1; #2), 83.0),
#   ("Median" (1; #9), 59.0),
#   ("10Percentile" (1; #0), 55.0),
#   ("Minimum" (1; #10), 44.0),
#   ("MeanAbsoluteDeviation" (1; #8), 40.0),
#   ("Maximum" (1; #6), 39.0),
#   ("90Percentile" (1; #1), 33.0),
#   ("Range" (1; #11), 27.0),
#   ("Skewness" (1; #14), 27.0),
#   ("Variance" (1; #17), 23.0),
#   ("RobustMeanAbsoluteDeviation" (1; #12), 18.0),
#   ("InterquartileRange" (1; #4), 14.0),
#   ("Kurtosis" (1; #5), 10.0),
#   ("Entropy" (1; #3), 8.0),
#   ("Uniformity" (1; #16), 6.0)]}

# %%
# Model self evaluation
model.make_inspector().evaluation()
# Out:
# Evaluation(num_examples=None, accuracy=0.986011266708374, loss=0.05883138254284859, rmse=None, ndcg=None, aucs=None, auuc=None, qini=None)

# %%
logs = model.make_inspector().training_logs()

plt.figure(figsize=(12, 4))
plt.subplot(1, 2, 1)
plt.plot([log.num_trees for log in logs], [log.evaluation.accuracy for log in logs])
plt.xlabel("Number of trees")
plt.ylabel("Accuracy (out-of-bag)")
plt.subplot(1, 2, 2)
plt.plot([log.num_trees for log in logs], [log.evaluation.loss for log in logs])
plt.xlabel("Number of trees")
plt.ylabel("Logloss (out-of-bag)")
plt.show()

# %% [markdown]
# Calculate the score of our hold-out validation dataset

# %%
predictions = model.predict(val_ds)
y_true      = validation_data["label"]

from sklearn.metrics import roc_auc_score
ROC_AUC = roc_auc_score(y_true, predictions)
print("The ROC AUC score is %.5f" % ROC_AUC )
# Out:
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 60ms/step
# The ROC AUC score is 1.00000

# %%
# Compute binary classification metrics with sklearn
import numpy as np
from sklearn.metrics import (
    accuracy_score,
    precision_score,
    recall_score,
    f1_score,
    roc_auc_score,
    average_precision_score,
    confusion_matrix,
    classification_report,
    matthews_corrcoef,
    log_loss,
    brier_score_loss,
)

# Get predictions (probabilities or class labels)
preds = model.predict(test_ds)
# If model outputs probabilities, convert to labels by threshold 0.5
if preds.ndim == 2:
    # For TFDF classification, preds may be class probabilities with shape (N, 2)
    if preds.shape[1] == 2:
        pos_probs = preds[:, 1]
    else:
        # If single-probability column (positive class)
        pos_probs = preds[:, -1]
    y_pred = (pos_probs >= 0.5).astype(int)
else:
    # Already class labels
    y_pred = preds.astype(int)
    pos_probs = None

# Ground truth labels (must be 0/1 integers)
y_true = test_data["label"].astype(int).to_numpy()

# Core metrics
metrics = {}
metrics["accuracy"] = accuracy_score(y_true, y_pred)
metrics["precision"] = precision_score(y_true, y_pred, zero_division=0)
metrics["recall"] = recall_score(y_true, y_pred, zero_division=0)
metrics["f1"] = f1_score(y_true, y_pred, zero_division=0)
metrics["mcc"] = matthews_corrcoef(y_true, y_pred)

# Probabilistic metrics (only if we have probabilities)
if pos_probs is not None:
    metrics["roc_auc"] = roc_auc_score(y_true, pos_probs)
    metrics["pr_auc"] = average_precision_score(y_true, pos_probs)
    metrics["log_loss"] = log_loss(y_true, pos_probs, labels=[0,1])
    metrics["brier_score"] = brier_score_loss(y_true, pos_probs)

# Confusion matrix and detailed report
cm = confusion_matrix(y_true, y_pred, labels=[0,1])
report = classification_report(y_true, y_pred, digits=4)

print("Sklearn binary metrics:")
for k, v in metrics.items():
    print(f"{k}: {v:.4f}")
print("\nConfusion matrix:\n", cm)
print("\nClassification report:\n", report)
# Out:
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 60ms/step
# Sklearn binary metrics:
# accuracy: 1.0000
# precision: 1.0000
# recall: 1.0000
# f1: 1.0000
# mcc: 1.0000
# roc_auc: 1.0000
# pr_auc: 1.0000
# log_loss: 0.0089
# brier_score: 0.0007
#
# Confusion matrix:
#  [[337   0]
#  [  0 105]]
#
# Classification report:
#                precision    recall  f1-score   support
#
#            0     1.0000    1.0000    1.0000       337
#            1     1.0000    1.0000    1.0000       105
#
#     accuracy                         1.0000       442
#    macro avg     1.0000    1.0000    1.0000       442
# weighted avg     1.0000    1.0000    1.0000       442
