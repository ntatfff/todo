# %%
# Import packages and modules
import numpy  as np
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow_decision_forests as tfdf

from sklearn.model_selection import train_test_split
# Out:
# 2026-08-15 04:58:02.414935: I tensorflow/core/util/port.cc:113] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2026-08-15 04:58:02.811776: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2026-08-15 04:58:07.578466: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
# Check the version of TensorFlow Decision Forests
print("Found TensorFlow Decision Forests v" + tfdf.__version__)
# Out:
# Found TensorFlow Decision Forests v1.9.1

# %%
datasetPath = 'dataset/firstorder/kernel5/dataset.csv'

# %%
# Parameters
datasetPath = "dataset/firstorder/kernel4/1.dataset.csv"

# %%
# train/validation/test = 70/10/20
dataset = pd.read_csv(datasetPath)

train_data, temp_data = train_test_split(dataset, test_size=0.3, random_state=42)
validation_data, test_data = train_test_split(temp_data, test_size=2/3, random_state=42)

# %%
from sklearn.utils.class_weight import compute_class_weight

# tinh class weight tren tap train
classes = np.array([0, 1])
weights = compute_class_weight(class_weight="balanced", classes=classes, y=train_data["label"])
class_weight = {0: weights[0], 1: weights[1]}

# gan sample_weight cho tung dong
train_data["sample_weight"] = train_data["label"].map(class_weight)
validation_data["sample_weight"] = validation_data["label"].map(class_weight)
test_data["sample_weight"] = test_data["label"].map(class_weight)

# Convert the dataset into a TensorFlow dataset.
train_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    train_data, label="label", weight="sample_weight"
)         
val_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    validation_data, label="label", weight="sample_weight"
)
test_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    test_data, label="label", weight="sample_weight"
)
# Out:
# 2026-08-15 04:58:21.091326: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:984] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2026-08-15 04:58:21.092766: W tensorflow/core/common_runtime/gpu/gpu_device.cc:2251] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...

# %%
import keras

# %%
# %%time

# Train a Gradient Boosted Trees model.
model = tfdf.keras.GradientBoostedTreesModel()

# Add evaluation metrics
model.compile(
    metrics=["accuracy"]
)
model.fit(x=train_ds)

# # Train a Gradient Boosted Trees model.
# model = tfdf.keras.GradientBoostedTreesModel(num_trees=1500)
# model.fit(train_ds)
# Out:
# Use /tmp/tmp2mcde7sn as temporary training directory
# Reading training dataset...
# [WARNING 26-08-15 04:58:21.2523 UTC gradient_boosted_trees.cc:1840] "goss_alpha" set but "sampling_method" not equal to "GOSS".
# [WARNING 26-08-15 04:58:21.2527 UTC gradient_boosted_trees.cc:1851] "goss_beta" set but "sampling_method" not equal to "GOSS".
# [WARNING 26-08-15 04:58:21.2527 UTC gradient_boosted_trees.cc:1865] "selective_gradient_boosting_ratio" set but "sampling_method" not equal to "SELGB".
# Training dataset read in 0:00:02.730900. Found 1554 examples.
# Training model...
# Model trained in 0:00:00.211256
# Compiling model...
# [INFO 26-08-15 04:58:24.2283 UTC kernel.cc:1233] Loading model from path /tmp/tmp2mcde7sn/model/ with prefix f2c90f9eb1f4481e
# [INFO 26-08-15 04:58:24.2299 UTC quick_scorer_extended.cc:911] The binary was compiled without AVX2 support, but your CPU supports it. Enable it for faster model inference.
# [INFO 26-08-15 04:58:24.2300 UTC abstract_model.cc:1362] Engine "GradientBoostedTreesQuickScorerExtended" built
# [INFO 26-08-15 04:58:24.2300 UTC kernel.cc:1061] Use fast generic engine
# Model compiled.
# CPU times: user 5.94 s, sys: 313 ms, total: 6.25 s
# Wall time: 6.26 s

# %%
# Evaluate the model
evaluate = model.evaluate(val_ds, return_dict=True)
print()

for name, value in evaluate.items():
    print(f"{name}: {value:.4f}")
# Out:
# WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 1/1 [==============================] - ETA: 0s - loss: 0.0000e+00 - accuracy: 1.0000
# 1/1 [==============================] - 3s 3s/step - loss: 0.0000e+00 - accuracy: 1.0000
# loss: 0.0000
# accuracy: 1.0000

# %%
# Model Summary
model.summary()
# Out:
# Model: "gradient_boosted_trees_model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
# =================================================================
# Total params: 1 (1.00 Byte)
# Trainable params: 0 (0.00 Byte)
# Non-trainable params: 1 (1.00 Byte)
# _________________________________________________________________
# Type: "GRADIENT_BOOSTED_TREES"
# Task: CLASSIFICATION
# Label: "__LABEL"
#
# Input Features (18):
# 	10Percentile
# 	90Percentile
# 	Energy
# 	Entropy
# 	InterquartileRange
# 	Kurtosis
# 	Maximum
# 	Mean
# 	MeanAbsoluteDeviation
# 	Median
# 	Minimum
# 	Range
# 	RobustMeanAbsoluteDeviation
# 	RootMeanSquared
# 	Skewness
# 	TotalEnergy
# 	Uniformity
# 	Variance
#
# Trained with weights
#
# Variable Importance: INV_MEAN_MIN_DEPTH:
#     1.                "90Percentile"  1.000000 ################
#     2.                     "Maximum"  0.298114 #
#     3.                     "Entropy"  0.258888 #
#     4.                    "Skewness"  0.237155
#     5.                     "Minimum"  0.217639
#     6.                      "Median"  0.217103
#     7.                    "Kurtosis"  0.216618
#     8.                 "TotalEnergy"  0.215475
#     9.                      "Energy"  0.214274
#    10.                  "Uniformity"  0.212437
#    11.             "RootMeanSquared"  0.209481
#    12.                    "Variance"  0.209204
#    13.                        "Mean"  0.208726
#    14.                       "Range"  0.208717
#    15.                "10Percentile"  0.208559
#    16. "RobustMeanAbsoluteDeviation"  0.208114
#    17.       "MeanAbsoluteDeviation"  0.207713
#    18.          "InterquartileRange"  0.207175
#
# Variable Importance: NUM_AS_ROOT:
#     1. "90Percentile" 16.000000
#
# Variable Importance: NUM_NODES:
#     1.                "90Percentile" 34.000000 ################
#     2.                     "Entropy" 24.000000 ###########
#     3.                     "Maximum" 18.000000 ########
#     4.                    "Skewness" 15.000000 ######
#     5.                     "Minimum" 12.000000 #####
#     6.                      "Median" 10.000000 ####
#     7.                       "Range"  8.000000 ###
#     8.                    "Kurtosis"  7.000000 ##
#     9.                  "Uniformity"  6.000000 ##
#    10.                      "Energy"  5.000000 #
#    11.                        "Mean"  5.000000 #
#    12.             "RootMeanSquared"  5.000000 #
#    13.                 "TotalEnergy"  5.000000 #
#    14.                    "Variance"  4.000000 #
#    15. "RobustMeanAbsoluteDeviation"  3.000000
#    16.                "10Percentile"  2.000000
#    17.          "InterquartileRange"  2.000000
#    18.       "MeanAbsoluteDeviation"  1.000000
#
# Variable Importance: SUM_SCORE:
#     1.                "90Percentile" 1678.541898 ################
#     2.                     "Entropy" 34.249604
#     3.                     "Maximum" 33.269676
#     4.                    "Skewness" 16.386266
#     5.                     "Minimum"  9.802060
#     6.                        "Mean"  6.234308
#     7.                    "Kurtosis"  6.167431
#     8.                 "TotalEnergy"  3.167570
#     9.                      "Energy"  1.920497
#    10.             "RootMeanSquared"  1.590447
#    11.                  "Uniformity"  0.782735
#    12.                      "Median"  0.763316
#    13.                    "Variance"  0.754979
#    14.                "10Percentile"  0.481773
#    15.                       "Range"  0.028601
#    16.       "MeanAbsoluteDeviation"  0.000000
#    17. "RobustMeanAbsoluteDeviation"  0.000000
#    18.          "InterquartileRange"  0.000000
#
#
#
# Loss: BINOMIAL_LOG_LIKELIHOOD
# Validation loss value: 0.659527
# Number of trees per iteration: 1
# Node format: NOT_SET
# Number of trees: 16
# Total number of nodes: 348
#
# Number of nodes by tree:
# Count: 16 Average: 21.75 StdDev: 4.63006
# Min: 17 Max: 31 Ignored: 0
# ----------------------------------------------
# [ 17, 18) 1   6.25%   6.25% #
# [ 18, 19) 0   0.00%   6.25%
# [ 19, 20) 8  50.00%  56.25% ##########
# [ 20, 21) 0   0.00%  56.25%
# [ 21, 22) 3  18.75%  75.00% ####
# [ 22, 23) 0   0.00%  75.00%
# [ 23, 24) 1   6.25%  81.25% #
# [ 24, 25) 0   0.00%  81.25%
# [ 25, 26) 0   0.00%  81.25%
# [ 26, 27) 0   0.00%  81.25%
# [ 27, 28) 0   0.00%  81.25%
# [ 28, 29) 0   0.00%  81.25%
# [ 29, 30) 0   0.00%  81.25%
# [ 30, 31) 0   0.00%  81.25%
# [ 31, 31] 3  18.75% 100.00% ####
#
# Depth by leafs:
# Count: 182 Average: 3.91758 StdDev: 1.06328
# Min: 2 Max: 5 Ignored: 0
# ----------------------------------------------
# [ 2, 3) 22  12.09%  12.09% ###
# [ 3, 4) 45  24.73%  36.81% ######
# [ 4, 5) 41  22.53%  59.34% ######
# [ 5, 5] 74  40.66% 100.00% ##########
#
# Number of training obs by leaf:
# Count: 182 Average: 125.275 StdDev: 320.059
# Min: 5 Max: 1278 Ignored: 0
# ----------------------------------------------
# [    5,   68) 144  79.12%  79.12% ##########
# [   68,  132)  17   9.34%  88.46% #
# [  132,  196)   0   0.00%  88.46%
# [  196,  259)   1   0.55%  89.01%
# [  259,  323)   1   0.55%  89.56%
# [  323,  387)   2   1.10%  90.66%
# [  387,  450)   1   0.55%  91.21%
# [  450,  514)   0   0.00%  91.21%
# [  514,  578)   0   0.00%  91.21%
# [  578,  642)   0   0.00%  91.21%
# [  642,  705)   0   0.00%  91.21%
# [  705,  769)   1   0.55%  91.76%
# [  769,  833)   0   0.00%  91.76%
# [  833,  896)   0   0.00%  91.76%
# [  896,  960)   2   1.10%  92.86%
# [  960, 1024)   2   1.10%  93.96%
# [ 1024, 1087)   0   0.00%  93.96%
# [ 1087, 1151)   0   0.00%  93.96%
# [ 1151, 1215)   4   2.20%  96.15%
# [ 1215, 1278]   7   3.85% 100.00%
#
# Attribute in nodes:
# 	34 : 90Percentile [NUMERICAL]
# 	24 : Entropy [NUMERICAL]
# 	18 : Maximum [NUMERICAL]
# 	15 : Skewness [NUMERICAL]
# 	12 : Minimum [NUMERICAL]
# 	10 : Median [NUMERICAL]
# 	8 : Range [NUMERICAL]
# 	7 : Kurtosis [NUMERICAL]
# 	6 : Uniformity [NUMERICAL]
# 	5 : TotalEnergy [NUMERICAL]
# 	5 : RootMeanSquared [NUMERICAL]
# 	5 : Mean [NUMERICAL]
# 	5 : Energy [NUMERICAL]
# 	4 : Variance [NUMERICAL]
# 	3 : RobustMeanAbsoluteDeviation [NUMERICAL]
# 	2 : InterquartileRange [NUMERICAL]
# 	2 : 10Percentile [NUMERICAL]
# 	1 : MeanAbsoluteDeviation [NUMERICAL]
#
# Attribute in nodes with depth <= 0:
# 	16 : 90Percentile [NUMERICAL]
#
# Attribute in nodes with depth <= 1:
# 	19 : 90Percentile [NUMERICAL]
# 	15 : Entropy [NUMERICAL]
# 	13 : Maximum [NUMERICAL]
# 	1 : Uniformity [NUMERICAL]
#
# Attribute in nodes with depth <= 2:
# 	22 : Entropy [NUMERICAL]
# 	20 : 90Percentile [NUMERICAL]
# 	14 : Maximum [NUMERICAL]
# 	6 : Skewness [NUMERICAL]
# 	5 : Kurtosis [NUMERICAL]
# 	5 : Energy [NUMERICAL]
# 	4 : TotalEnergy [NUMERICAL]
# 	4 : Median [NUMERICAL]
# 	3 : RootMeanSquared [NUMERICAL]
# 	2 : Variance [NUMERICAL]
# 	2 : Uniformity [NUMERICAL]
# 	1 : Range [NUMERICAL]
# 	1 : MeanAbsoluteDeviation [NUMERICAL]
# 	1 : 10Percentile [NUMERICAL]
#
# Attribute in nodes with depth <= 3:
# 	26 : 90Percentile [NUMERICAL]
# 	24 : Entropy [NUMERICAL]
# 	18 : Maximum [NUMERICAL]
# 	14 : Skewness [NUMERICAL]
# 	6 : Minimum [NUMERICAL]
# 	6 : Median [NUMERICAL]
# 	5 : Kurtosis [NUMERICAL]
# 	5 : Energy [NUMERICAL]
# 	4 : Variance [NUMERICAL]
# 	4 : TotalEnergy [NUMERICAL]
# 	3 : Uniformity [NUMERICAL]
# 	3 : RootMeanSquared [NUMERICAL]
# 	2 : RobustMeanAbsoluteDeviation [NUMERICAL]
# 	2 : Range [NUMERICAL]
# 	2 : Mean [NUMERICAL]
# 	2 : InterquartileRange [NUMERICAL]
# 	2 : 10Percentile [NUMERICAL]
# 	1 : MeanAbsoluteDeviation [NUMERICAL]
#
# Attribute in nodes with depth <= 5:
# 	34 : 90Percentile [NUMERICAL]
# 	24 : Entropy [NUMERICAL]
# 	18 : Maximum [NUMERICAL]
# 	15 : Skewness [NUMERICAL]
# 	12 : Minimum [NUMERICAL]
# 	10 : Median [NUMERICAL]
# 	8 : Range [NUMERICAL]
# 	7 : Kurtosis [NUMERICAL]
# 	6 : Uniformity [NUMERICAL]
# 	5 : TotalEnergy [NUMERICAL]
# 	5 : RootMeanSquared [NUMERICAL]
# 	5 : Mean [NUMERICAL]
# 	5 : Energy [NUMERICAL]
# 	4 : Variance [NUMERICAL]
# 	3 : RobustMeanAbsoluteDeviation [NUMERICAL]
# 	2 : InterquartileRange [NUMERICAL]
# 	2 : 10Percentile [NUMERICAL]
# 	1 : MeanAbsoluteDeviation [NUMERICAL]
#
# Condition type in nodes:
# 	166 : HigherCondition
# Condition type in nodes with depth <= 0:
# 	16 : HigherCondition
# Condition type in nodes with depth <= 1:
# 	48 : HigherCondition
# Condition type in nodes with depth <= 2:
# 	90 : HigherCondition
# Condition type in nodes with depth <= 3:
# 	129 : HigherCondition
# Condition type in nodes with depth <= 5:
# 	166 : HigherCondition
#
# Training logs:
# Number of iteration to final model: 16
# 	Iter:1 train-loss:1.200310 valid-loss:1.247053  train-accuracy:0.993196 valid-accuracy:0.879977
# 	Iter:2 train-loss:1.048274 valid-loss:1.134301  train-accuracy:0.994330 valid-accuracy:0.883645
# 	Iter:3 train-loss:0.921556 valid-loss:1.044132  train-accuracy:0.992818 valid-accuracy:0.879977
# 	Iter:4 train-loss:0.814140 valid-loss:0.971045  train-accuracy:0.994330 valid-accuracy:0.883645
# 	Iter:5 train-loss:0.722689 valid-loss:0.913112  train-accuracy:0.993574 valid-accuracy:0.879977
# 	Iter:6 train-loss:0.644500 valid-loss:0.865637  train-accuracy:0.993952 valid-accuracy:0.883645
# 	Iter:16 train-loss:0.226521 valid-loss:0.659527  train-accuracy:0.996976 valid-accuracy:0.883645
# 	Iter:26 train-loss:0.085042 valid-loss:0.691087  train-accuracy:0.998110 valid-accuracy:0.883645
# 	Iter:36 train-loss:0.033969 valid-loss:0.780465  train-accuracy:0.999622 valid-accuracy:0.883645
# 	Iter:46 train-loss:0.014487 valid-loss:0.881087  train-accuracy:1.000000 valid-accuracy:0.883645

# %%
# Model features
model.make_inspector().features()
# Out:
# ["10Percentile" (1; #0),
#  "90Percentile" (1; #1),
#  "Energy" (1; #2),
#  "Entropy" (1; #3),
#  "InterquartileRange" (1; #4),
#  "Kurtosis" (1; #5),
#  "Maximum" (1; #6),
#  "Mean" (1; #7),
#  "MeanAbsoluteDeviation" (1; #8),
#  "Median" (1; #9),
#  "Minimum" (1; #10),
#  "Range" (1; #11),
#  "RobustMeanAbsoluteDeviation" (1; #12),
#  "RootMeanSquared" (1; #13),
#  "Skewness" (1; #14),
#  "TotalEnergy" (1; #15),
#  "Uniformity" (1; #16),
#  "Variance" (1; #17)]

# %%
# Feature importance
model.make_inspector().variable_importances()
# Out:
# {'INV_MEAN_MIN_DEPTH': [("90Percentile" (1; #1), 1.0),
#   ("Maximum" (1; #6), 0.2981135005046192),
#   ("Entropy" (1; #3), 0.2588875110066009),
#   ("Skewness" (1; #14), 0.2371554816939998),
#   ("Minimum" (1; #10), 0.21763921902694386),
#   ("Median" (1; #9), 0.2171034033768214),
#   ("Kurtosis" (1; #5), 0.21661797662536128),
#   ("TotalEnergy" (1; #15), 0.21547539088072504),
#   ("Energy" (1; #2), 0.21427375704480778),
#   ("Uniformity" (1; #16), 0.21243673586395465),
#   ("RootMeanSquared" (1; #13), 0.2094805141133198),
#   ("Variance" (1; #17), 0.2092035012530418),
#   ("Mean" (1; #7), 0.2087259023046818),
#   ("Range" (1; #11), 0.20871730762579122),
#   ("10Percentile" (1; #0), 0.2085589485153012),
#   ("RobustMeanAbsoluteDeviation" (1; #12), 0.2081140159994219),
#   ("MeanAbsoluteDeviation" (1; #8), 0.20771284747890822),
#   ("InterquartileRange" (1; #4), 0.20717493627964692)],
#  'NUM_AS_ROOT': [("90Percentile" (1; #1), 16.0)],
#  'SUM_SCORE': [("90Percentile" (1; #1), 1678.5418981380062),
#   ("Entropy" (1; #3), 34.249603824339566),
#   ("Maximum" (1; #6), 33.269676473127724),
#   ("Skewness" (1; #14), 16.386265563899844),
#   ("Minimum" (1; #10), 9.802060242347105),
#   ("Mean" (1; #7), 6.234308020014757),
#   ("Kurtosis" (1; #5), 6.1674309160972145),
#   ("TotalEnergy" (1; #15), 3.1675701253608004),
#   ("Energy" (1; #2), 1.920496966409996),
#   ("RootMeanSquared" (1; #13), 1.59044694590628),
#   ("Uniformity" (1; #16), 0.7827345297733225),
#   ("Median" (1; #9), 0.7633160176036835),
#   ("Variance" (1; #17), 0.7549788290316113),
#   ("10Percentile" (1; #0), 0.481772839524365),
#   ("Range" (1; #11), 0.02860114413812441),
#   ("MeanAbsoluteDeviation" (1; #8), 1.0214052374894663e-14),
#   ("RobustMeanAbsoluteDeviation" (1; #12), 6.661338129190359e-15),
#   ("InterquartileRange" (1; #4), 9.992007464815739e-16)],
#  'NUM_NODES': [("90Percentile" (1; #1), 34.0),
#   ("Entropy" (1; #3), 24.0),
#   ("Maximum" (1; #6), 18.0),
#   ("Skewness" (1; #14), 15.0),
#   ("Minimum" (1; #10), 12.0),
#   ("Median" (1; #9), 10.0),
#   ("Range" (1; #11), 8.0),
#   ("Kurtosis" (1; #5), 7.0),
#   ("Uniformity" (1; #16), 6.0),
#   ("Energy" (1; #2), 5.0),
#   ("Mean" (1; #7), 5.0),
#   ("RootMeanSquared" (1; #13), 5.0),
#   ("TotalEnergy" (1; #15), 5.0),
#   ("Variance" (1; #17), 4.0),
#   ("RobustMeanAbsoluteDeviation" (1; #12), 3.0),
#   ("10Percentile" (1; #0), 2.0),
#   ("InterquartileRange" (1; #4), 2.0),
#   ("MeanAbsoluteDeviation" (1; #8), 1.0)]}

# %%
# Model self evaluation
model.make_inspector().evaluation()
# Out:
# Evaluation(num_examples=None, accuracy=0.8836454749107361, loss=0.6595265865325928, rmse=None, ndcg=None, aucs=None, auuc=None, qini=None)

# %%
logs = model.make_inspector().training_logs()

plt.figure(figsize=(12, 4))
plt.subplot(1, 2, 1)
plt.plot([log.num_trees for log in logs], [log.evaluation.accuracy for log in logs])
plt.xlabel("Number of trees")
plt.ylabel("Accuracy (out-of-bag)")
plt.subplot(1, 2, 2)
plt.plot([log.num_trees for log in logs], [log.evaluation.loss for log in logs])
plt.xlabel("Number of trees")
plt.ylabel("Logloss (out-of-bag)")
plt.show()

# %% [markdown]
# Calculate the score of our hold-out validation dataset

# %%
predictions = model.predict(val_ds)
y_true      = validation_data["label"]

from sklearn.metrics import roc_auc_score
ROC_AUC = roc_auc_score(y_true, predictions)
print("The ROC AUC score is %.5f" % ROC_AUC )
# Out:
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 62ms/step
# The ROC AUC score is 1.00000

# %%
# Compute binary classification metrics with sklearn
import numpy as np
from sklearn.metrics import (
    accuracy_score,
    precision_score,
    recall_score,
    f1_score,
    roc_auc_score,
    average_precision_score,
    confusion_matrix,
    classification_report,
    matthews_corrcoef,
    log_loss,
    brier_score_loss,
)

# Get predictions (probabilities or class labels)
preds = model.predict(test_ds)
# If model outputs probabilities, convert to labels by threshold 0.5
if preds.ndim == 2:
    # For TFDF classification, preds may be class probabilities with shape (N, 2)
    if preds.shape[1] == 2:
        pos_probs = preds[:, 1]
    else:
        # If single-probability column (positive class)
        pos_probs = preds[:, -1]
    y_pred = (pos_probs >= 0.5).astype(int)
else:
    # Already class labels
    y_pred = preds.astype(int)
    pos_probs = None

# Ground truth labels (must be 0/1 integers)
y_true = test_data["label"].astype(int).to_numpy()

# Core metrics
metrics = {}
metrics["accuracy"] = accuracy_score(y_true, y_pred)
metrics["precision"] = precision_score(y_true, y_pred, zero_division=0)
metrics["recall"] = recall_score(y_true, y_pred, zero_division=0)
metrics["f1"] = f1_score(y_true, y_pred, zero_division=0)
metrics["mcc"] = matthews_corrcoef(y_true, y_pred)

# Probabilistic metrics (only if we have probabilities)
if pos_probs is not None:
    metrics["roc_auc"] = roc_auc_score(y_true, pos_probs)
    metrics["pr_auc"] = average_precision_score(y_true, pos_probs)
    metrics["log_loss"] = log_loss(y_true, pos_probs, labels=[0,1])
    metrics["brier_score"] = brier_score_loss(y_true, pos_probs)

# Confusion matrix and detailed report
cm = confusion_matrix(y_true, y_pred, labels=[0,1])
report = classification_report(y_true, y_pred, digits=4)

print("Sklearn binary metrics:")
for k, v in metrics.items():
    print(f"{k}: {v:.4f}")
print("\nConfusion matrix:\n", cm)
print("\nClassification report:\n", report)
# Out:
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 68ms/step
# Sklearn binary metrics:
# accuracy: 0.9842
# precision: 0.8421
# recall: 0.9697
# f1: 0.9014
# mcc: 0.8955
# roc_auc: 0.9983
# pr_auc: 0.9645
# log_loss: 0.1306
# brier_score: 0.0203
#
# Confusion matrix:
#  [[405   6]
#  [  1  32]]
#
# Classification report:
#                precision    recall  f1-score   support
#
#            0     0.9975    0.9854    0.9914       411
#            1     0.8421    0.9697    0.9014        33
#
#     accuracy                         0.9842       444
#    macro avg     0.9198    0.9775    0.9464       444
# weighted avg     0.9860    0.9842    0.9847       444
