# %%
# Import packages and modules
import numpy  as np
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow_decision_forests as tfdf

from sklearn.model_selection import train_test_split
# Out:
# 2026-08-15 05:15:05.150096: I tensorflow/core/util/port.cc:113] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2026-08-15 05:15:05.508936: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2026-08-15 05:15:10.211054: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
# Check the version of TensorFlow Decision Forests
print("Found TensorFlow Decision Forests v" + tfdf.__version__)
# Out:
# Found TensorFlow Decision Forests v1.9.1

# %%
datasetPath = 'dataset/firstorder/kernel5/dataset.csv'

# %%
# Parameters
datasetPath = "dataset/glszm/kernel4/1.dataset.csv"

# %%
# train/validation/test = 70/10/20
dataset = pd.read_csv(datasetPath)

train_data, temp_data = train_test_split(dataset, test_size=0.3, random_state=42)
validation_data, test_data = train_test_split(temp_data, test_size=2/3, random_state=42)

# %%
from sklearn.utils.class_weight import compute_class_weight

# tinh class weight tren tap train
classes = np.array([0, 1])
weights = compute_class_weight(class_weight="balanced", classes=classes, y=train_data["label"])
class_weight = {0: weights[0], 1: weights[1]}

# gan sample_weight cho tung dong
train_data["sample_weight"] = train_data["label"].map(class_weight)
validation_data["sample_weight"] = validation_data["label"].map(class_weight)
test_data["sample_weight"] = test_data["label"].map(class_weight)

# Convert the dataset into a TensorFlow dataset.
train_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    train_data, label="label", weight="sample_weight"
)         
val_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    validation_data, label="label", weight="sample_weight"
)
test_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    test_data, label="label", weight="sample_weight"
)
# Out:
# 2026-08-15 05:15:23.198994: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:984] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2026-08-15 05:15:23.201206: W tensorflow/core/common_runtime/gpu/gpu_device.cc:2251] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...

# %%
import keras

# %%
# %%time

# Train a Random Forest model.
model = tfdf.keras.RandomForestModel()

# Add evaluation metrics
model.compile(
    metrics=["accuracy"]
)
model.fit(x=train_ds)

# # Train a Gradient Boosted Trees model.
# model = tfdf.keras.GradientBoostedTreesModel(num_trees=1500)
# model.fit(train_ds)
# Out:
# Use /tmp/tmpn_4ao0ng as temporary training directory
# Reading training dataset...
# Training dataset read in 0:00:02.708255. Found 1554 examples.
# Training model...
# Model trained in 0:00:00.065039
# Compiling model...
# [INFO 26-08-15 05:15:26.1407 UTC kernel.cc:1233] Loading model from path /tmp/tmpn_4ao0ng/model/ with prefix 7f7afca4bce74ace
# [INFO 26-08-15 05:15:26.1492 UTC decision_forest.cc:734] Model loaded with 300 root(s), 6720 node(s), and 16 input feature(s).
# [INFO 26-08-15 05:15:26.1493 UTC abstract_model.cc:1362] Engine "RandomForestOptPred" built
# [INFO 26-08-15 05:15:26.1493 UTC kernel.cc:1061] Use fast generic engine
# Model compiled.
# CPU times: user 5.75 s, sys: 84.5 ms, total: 5.84 s
# Wall time: 5.98 s

# %%
# Evaluate the model
evaluate = model.evaluate(val_ds, return_dict=True)
print()

for name, value in evaluate.items():
    print(f"{name}: {value:.4f}")
# Out:
# WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 1/1 [==============================] - ETA: 0s - loss: 0.0000e+00 - accuracy: 0.9820
# 1/1 [==============================] - 3s 3s/step - loss: 0.0000e+00 - accuracy: 0.9820
# loss: 0.0000
# accuracy: 0.9820

# %%
# Model Summary
model.summary()
# Out:
# Model: "random_forest_model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
# =================================================================
# Total params: 1 (1.00 Byte)
# Trainable params: 0 (0.00 Byte)
# Non-trainable params: 1 (1.00 Byte)
# _________________________________________________________________
# Type: "RANDOM_FOREST"
# Task: CLASSIFICATION
# Label: "__LABEL"
#
# Input Features (16):
# 	GrayLevelNonUniformity
# 	GrayLevelNonUniformityNormalized
# 	GrayLevelVariance
# 	HighGrayLevelZoneEmphasis
# 	LargeAreaEmphasis
# 	LargeAreaHighGrayLevelEmphasis
# 	LargeAreaLowGrayLevelEmphasis
# 	LowGrayLevelZoneEmphasis
# 	SizeZoneNonUniformity
# 	SizeZoneNonUniformityNormalized
# 	SmallAreaEmphasis
# 	SmallAreaHighGrayLevelEmphasis
# 	SmallAreaLowGrayLevelEmphasis
# 	ZoneEntropy
# 	ZonePercentage
# 	ZoneVariance
#
# Trained with weights
#
# Variable Importance: INV_MEAN_MIN_DEPTH:
#     1.        "HighGrayLevelZoneEmphasis"  0.332686 ################
#     2.   "SmallAreaHighGrayLevelEmphasis"  0.289491 ##########
#     3.         "LowGrayLevelZoneEmphasis"  0.265522 ########
#     4.    "LargeAreaLowGrayLevelEmphasis"  0.239455 ####
#     5.    "SmallAreaLowGrayLevelEmphasis"  0.236291 ####
#     6.           "GrayLevelNonUniformity"  0.225315 ###
#     7. "GrayLevelNonUniformityNormalized"  0.224179 ###
#     8.                      "ZoneEntropy"  0.220906 ##
#     9.                "GrayLevelVariance"  0.211927 #
#    10.                     "ZoneVariance"  0.205288
#    11.                "LargeAreaEmphasis"  0.203397
#    12.   "LargeAreaHighGrayLevelEmphasis"  0.201179
#    13.                   "ZonePercentage"  0.199416
#    14.  "SizeZoneNonUniformityNormalized"  0.199062
#    15.                "SmallAreaEmphasis"  0.198101
#    16.            "SizeZoneNonUniformity"  0.197598
#
# Variable Importance: NUM_AS_ROOT:
#     1.        "HighGrayLevelZoneEmphasis" 90.000000 ################
#     2.   "SmallAreaHighGrayLevelEmphasis" 64.000000 ###########
#     3.         "LowGrayLevelZoneEmphasis" 56.000000 #########
#     4.    "SmallAreaLowGrayLevelEmphasis" 40.000000 #######
#     5.    "LargeAreaLowGrayLevelEmphasis" 21.000000 ###
#     6.                      "ZoneEntropy" 12.000000 #
#     7. "GrayLevelNonUniformityNormalized" 11.000000 #
#     8.                "GrayLevelVariance"  5.000000
#     9.                "LargeAreaEmphasis"  1.000000
#
# Variable Importance: NUM_NODES:
#     1.        "HighGrayLevelZoneEmphasis" 488.000000 ################
#     2.   "SmallAreaHighGrayLevelEmphasis" 331.000000 ##########
#     3.    "LargeAreaLowGrayLevelEmphasis" 298.000000 #########
#     4.         "LowGrayLevelZoneEmphasis" 295.000000 ########
#     5.           "GrayLevelNonUniformity" 286.000000 ########
#     6.                      "ZoneEntropy" 272.000000 ########
#     7. "GrayLevelNonUniformityNormalized" 233.000000 ######
#     8.    "SmallAreaLowGrayLevelEmphasis" 206.000000 #####
#     9.                "GrayLevelVariance" 148.000000 ###
#    10.                     "ZoneVariance" 143.000000 ###
#    11.                "LargeAreaEmphasis" 138.000000 ###
#    12.   "LargeAreaHighGrayLevelEmphasis" 90.000000 #
#    13.                   "ZonePercentage" 81.000000 #
#    14.  "SizeZoneNonUniformityNormalized" 80.000000 #
#    15.                "SmallAreaEmphasis" 69.000000
#    16.            "SizeZoneNonUniformity" 52.000000
#
# Variable Importance: SUM_SCORE:
#     1.        "HighGrayLevelZoneEmphasis" 104762.512830 ################
#     2.   "SmallAreaHighGrayLevelEmphasis" 72738.279447 ###########
#     3.         "LowGrayLevelZoneEmphasis" 47110.994650 #######
#     4.    "SmallAreaLowGrayLevelEmphasis" 28341.474137 ####
#     5.    "LargeAreaLowGrayLevelEmphasis" 15965.809676 ##
#     6.                      "ZoneEntropy" 15376.910038 ##
#     7. "GrayLevelNonUniformityNormalized" 10255.257791 #
#     8.           "GrayLevelNonUniformity" 6400.264150
#     9.                "GrayLevelVariance" 5503.834408
#    10.                     "ZoneVariance" 3288.570486
#    11.                "LargeAreaEmphasis" 2696.847857
#    12.                   "ZonePercentage" 1580.021058
#    13.   "LargeAreaHighGrayLevelEmphasis" 1479.909918
#    14.  "SizeZoneNonUniformityNormalized" 795.504996
#    15.            "SizeZoneNonUniformity" 550.225276
#    16.                "SmallAreaEmphasis" 435.597008
#
#
#
# Winner takes all: true
# Out-of-bag evaluation: accuracy:0.962594 logloss:0.0773773
# Number of trees: 300
# Total number of nodes: 6720
#
# Number of nodes by tree:
# Count: 300 Average: 22.4 StdDev: 3.96148
# Min: 11 Max: 35 Ignored: 0
# ----------------------------------------------
# [ 11, 12)  1   0.33%   0.33%
# [ 12, 13)  0   0.00%   0.33%
# [ 13, 14)  1   0.33%   0.67%
# [ 14, 16) 10   3.33%   4.00% ##
# [ 16, 17)  0   0.00%   4.00%
# [ 17, 18) 25   8.33%  12.33% ####
# [ 18, 19)  0   0.00%  12.33%
# [ 19, 21) 49  16.33%  28.67% ########
# [ 21, 22) 55  18.33%  47.00% #########
# [ 22, 23)  0   0.00%  47.00%
# [ 23, 24) 64  21.33%  68.33% ##########
# [ 24, 26) 39  13.00%  81.33% ######
# [ 26, 27)  0   0.00%  81.33%
# [ 27, 28) 36  12.00%  93.33% ######
# [ 28, 29)  0   0.00%  93.33%
# [ 29, 31) 10   3.33%  96.67% ##
# [ 31, 32)  3   1.00%  97.67%
# [ 32, 33)  0   0.00%  97.67%
# [ 33, 34)  6   2.00%  99.67% #
# [ 34, 35]  1   0.33% 100.00%
#
# Depth by leafs:
# Count: 3510 Average: 4.1735 StdDev: 1.43812
# Min: 1 Max: 9 Ignored: 0
# ----------------------------------------------
# [ 1, 2)  23   0.66%   0.66%
# [ 2, 3) 393  11.20%  11.85% #####
# [ 3, 4) 836  23.82%  35.67% ##########
# [ 4, 5) 873  24.87%  60.54% ##########
# [ 5, 6) 727  20.71%  81.25% ########
# [ 6, 7) 448  12.76%  94.02% #####
# [ 7, 8) 169   4.81%  98.83% ##
# [ 8, 9)  35   1.00%  99.83%
# [ 9, 9]   6   0.17% 100.00%
#
# Number of training obs by leaf:
# Count: 3510 Average: 132.821 StdDev: 354.168
# Min: 5 Max: 1445 Ignored: 0
# ----------------------------------------------
# [    5,   77) 3022  86.10%  86.10% ##########
# [   77,  149)  113   3.22%  89.32%
# [  149,  221)   22   0.63%  89.94%
# [  221,  293)   20   0.57%  90.51%
# [  293,  365)   11   0.31%  90.83%
# [  365,  437)    8   0.23%  91.05%
# [  437,  509)    5   0.14%  91.20%
# [  509,  581)    5   0.14%  91.34%
# [  581,  653)    4   0.11%  91.45%
# [  653,  725)    2   0.06%  91.51%
# [  725,  797)    1   0.03%  91.54%
# [  797,  869)    7   0.20%  91.74%
# [  869,  941)    4   0.11%  91.85%
# [  941, 1013)   12   0.34%  92.19%
# [ 1013, 1085)   13   0.37%  92.56%
# [ 1085, 1157)   27   0.77%  93.33%
# [ 1157, 1229)   17   0.48%  93.82%
# [ 1229, 1301)   33   0.94%  94.76%
# [ 1301, 1373)  111   3.16%  97.92%
# [ 1373, 1445]   73   2.08% 100.00%
#
# Attribute in nodes:
# 	488 : HighGrayLevelZoneEmphasis [NUMERICAL]
# 	331 : SmallAreaHighGrayLevelEmphasis [NUMERICAL]
# 	298 : LargeAreaLowGrayLevelEmphasis [NUMERICAL]
# 	295 : LowGrayLevelZoneEmphasis [NUMERICAL]
# 	286 : GrayLevelNonUniformity [NUMERICAL]
# 	272 : ZoneEntropy [NUMERICAL]
# 	233 : GrayLevelNonUniformityNormalized [NUMERICAL]
# 	206 : SmallAreaLowGrayLevelEmphasis [NUMERICAL]
# 	148 : GrayLevelVariance [NUMERICAL]
# 	143 : ZoneVariance [NUMERICAL]
# 	138 : LargeAreaEmphasis [NUMERICAL]
# 	90 : LargeAreaHighGrayLevelEmphasis [NUMERICAL]
# 	81 : ZonePercentage [NUMERICAL]
# 	80 : SizeZoneNonUniformityNormalized [NUMERICAL]
# 	69 : SmallAreaEmphasis [NUMERICAL]
# 	52 : SizeZoneNonUniformity [NUMERICAL]
#
# Attribute in nodes with depth <= 0:
# 	90 : HighGrayLevelZoneEmphasis [NUMERICAL]
# 	64 : SmallAreaHighGrayLevelEmphasis [NUMERICAL]
# 	56 : LowGrayLevelZoneEmphasis [NUMERICAL]
# 	40 : SmallAreaLowGrayLevelEmphasis [NUMERICAL]
# 	21 : LargeAreaLowGrayLevelEmphasis [NUMERICAL]
# 	12 : ZoneEntropy [NUMERICAL]
# 	11 : GrayLevelNonUniformityNormalized [NUMERICAL]
# 	5 : GrayLevelVariance [NUMERICAL]
# 	1 : LargeAreaEmphasis [NUMERICAL]
#
# Attribute in nodes with depth <= 1:
# 	222 : HighGrayLevelZoneEmphasis [NUMERICAL]
# 	169 : SmallAreaHighGrayLevelEmphasis [NUMERICAL]
# 	107 : LowGrayLevelZoneEmphasis [NUMERICAL]
# 	75 : ZoneEntropy [NUMERICAL]
# 	62 : SmallAreaLowGrayLevelEmphasis [NUMERICAL]
# 	58 : GrayLevelNonUniformityNormalized [NUMERICAL]
# 	54 : LargeAreaLowGrayLevelEmphasis [NUMERICAL]
# 	43 : GrayLevelVariance [NUMERICAL]
# 	28 : GrayLevelNonUniformity [NUMERICAL]
# 	22 : ZoneVariance [NUMERICAL]
# 	14 : LargeAreaEmphasis [NUMERICAL]
# 	9 : LargeAreaHighGrayLevelEmphasis [NUMERICAL]
# 	8 : ZonePercentage [NUMERICAL]
# 	3 : SizeZoneNonUniformity [NUMERICAL]
# 	2 : SizeZoneNonUniformityNormalized [NUMERICAL]
# 	1 : SmallAreaEmphasis [NUMERICAL]
#
# Attribute in nodes with depth <= 2:
# 	348 : HighGrayLevelZoneEmphasis [NUMERICAL]
# 	234 : SmallAreaHighGrayLevelEmphasis [NUMERICAL]
# 	177 : LowGrayLevelZoneEmphasis [NUMERICAL]
# 	146 : ZoneEntropy [NUMERICAL]
# 	138 : LargeAreaLowGrayLevelEmphasis [NUMERICAL]
# 	116 : GrayLevelNonUniformityNormalized [NUMERICAL]
# 	109 : GrayLevelNonUniformity [NUMERICAL]
# 	108 : SmallAreaLowGrayLevelEmphasis [NUMERICAL]
# 	76 : GrayLevelVariance [NUMERICAL]
# 	55 : ZoneVariance [NUMERICAL]
# 	38 : LargeAreaEmphasis [NUMERICAL]
# 	33 : LargeAreaHighGrayLevelEmphasis [NUMERICAL]
# 	25 : ZonePercentage [NUMERICAL]
# 	12 : SizeZoneNonUniformityNormalized [NUMERICAL]
# 	12 : SizeZoneNonUniformity [NUMERICAL]
# 	11 : SmallAreaEmphasis [NUMERICAL]
#
# Attribute in nodes with depth <= 3:
# 	426 : HighGrayLevelZoneEmphasis [NUMERICAL]
# 	292 : SmallAreaHighGrayLevelEmphasis [NUMERICAL]
# 	234 : LowGrayLevelZoneEmphasis [NUMERICAL]
# 	212 : LargeAreaLowGrayLevelEmphasis [NUMERICAL]
# 	205 : ZoneEntropy [NUMERICAL]
# 	201 : GrayLevelNonUniformity [NUMERICAL]
# 	170 : GrayLevelNonUniformityNormalized [NUMERICAL]
# 	150 : SmallAreaLowGrayLevelEmphasis [NUMERICAL]
# 	106 : GrayLevelVariance [NUMERICAL]
# 	84 : ZoneVariance [NUMERICAL]
# 	65 : LargeAreaEmphasis [NUMERICAL]
# 	51 : LargeAreaHighGrayLevelEmphasis [NUMERICAL]
# 	39 : SizeZoneNonUniformityNormalized [NUMERICAL]
# 	35 : ZonePercentage [NUMERICAL]
# 	28 : SmallAreaEmphasis [NUMERICAL]
# 	26 : SizeZoneNonUniformity [NUMERICAL]
#
# Attribute in nodes with depth <= 5:
# 	484 : HighGrayLevelZoneEmphasis [NUMERICAL]
# 	323 : SmallAreaHighGrayLevelEmphasis [NUMERICAL]
# 	291 : LowGrayLevelZoneEmphasis [NUMERICAL]
# 	291 : LargeAreaLowGrayLevelEmphasis [NUMERICAL]
# 	276 : GrayLevelNonUniformity [NUMERICAL]
# 	263 : ZoneEntropy [NUMERICAL]
# 	225 : GrayLevelNonUniformityNormalized [NUMERICAL]
# 	198 : SmallAreaLowGrayLevelEmphasis [NUMERICAL]
# 	139 : GrayLevelVariance [NUMERICAL]
# 	137 : ZoneVariance [NUMERICAL]
# 	125 : LargeAreaEmphasis [NUMERICAL]
# 	87 : LargeAreaHighGrayLevelEmphasis [NUMERICAL]
# 	74 : ZonePercentage [NUMERICAL]
# 	73 : SizeZoneNonUniformityNormalized [NUMERICAL]
# 	59 : SmallAreaEmphasis [NUMERICAL]
# 	49 : SizeZoneNonUniformity [NUMERICAL]
#
# Condition type in nodes:
# 	3210 : HigherCondition
# Condition type in nodes with depth <= 0:
# 	300 : HigherCondition
# Condition type in nodes with depth <= 1:
# 	877 : HigherCondition
# Condition type in nodes with depth <= 2:
# 	1638 : HigherCondition
# Condition type in nodes with depth <= 3:
# 	2324 : HigherCondition
# Condition type in nodes with depth <= 5:
# 	3094 : HigherCondition
# Node format: NOT_SET
#
# Training OOB:
# 	trees: 1, Out-of-bag evaluation: accuracy:0.992553 logloss:0.26841
# 	trees: 13, Out-of-bag evaluation: accuracy:0.930967 logloss:1.4772
# 	trees: 23, Out-of-bag evaluation: accuracy:0.95694 logloss:0.118562
# 	trees: 33, Out-of-bag evaluation: accuracy:0.961217 logloss:0.116042
# 	trees: 47, Out-of-bag evaluation: accuracy:0.961905 logloss:0.0950433
# 	trees: 57, Out-of-bag evaluation: accuracy:0.957299 logloss:0.0902353
# 	trees: 67, Out-of-bag evaluation: accuracy:0.962938 logloss:0.0884328
# 	trees: 77, Out-of-bag evaluation: accuracy:0.962594 logloss:0.0888923
# 	trees: 87, Out-of-bag evaluation: accuracy:0.96225 logloss:0.0885434
# 	trees: 97, Out-of-bag evaluation: accuracy:0.962594 logloss:0.0895706
# 	trees: 107, Out-of-bag evaluation: accuracy:0.961905 logloss:0.0871618
# 	trees: 117, Out-of-bag evaluation: accuracy:0.961905 logloss:0.0869164
# 	trees: 127, Out-of-bag evaluation: accuracy:0.962594 logloss:0.0858454
# 	trees: 137, Out-of-bag evaluation: accuracy:0.962594 logloss:0.0855673
# 	trees: 148, Out-of-bag evaluation: accuracy:0.962594 logloss:0.0867416
# 	trees: 159, Out-of-bag evaluation: accuracy:0.962594 logloss:0.0870281
# 	trees: 169, Out-of-bag evaluation: accuracy:0.962594 logloss:0.0867897
# 	trees: 179, Out-of-bag evaluation: accuracy:0.962594 logloss:0.0875657
# 	trees: 190, Out-of-bag evaluation: accuracy:0.962594 logloss:0.0870819
# 	trees: 200, Out-of-bag evaluation: accuracy:0.962594 logloss:0.0866987
# 	trees: 210, Out-of-bag evaluation: accuracy:0.962594 logloss:0.0865302
# 	trees: 220, Out-of-bag evaluation: accuracy:0.962594 logloss:0.0859751
# 	trees: 230, Out-of-bag evaluation: accuracy:0.962594 logloss:0.0865794
# 	trees: 240, Out-of-bag evaluation: accuracy:0.962938 logloss:0.0868857
# 	trees: 251, Out-of-bag evaluation: accuracy:0.962938 logloss:0.0866283
# 	trees: 261, Out-of-bag evaluation: accuracy:0.962938 logloss:0.0872834
# 	trees: 271, Out-of-bag evaluation: accuracy:0.962938 logloss:0.0865128
# 	trees: 281, Out-of-bag evaluation: accuracy:0.96225 logloss:0.0765448
# 	trees: 291, Out-of-bag evaluation: accuracy:0.962594 logloss:0.0770456
# 	trees: 300, Out-of-bag evaluation: accuracy:0.962594 logloss:0.0773773

# %%
# Model features
model.make_inspector().features()
# Out:
# ["GrayLevelNonUniformity" (1; #0),
#  "GrayLevelNonUniformityNormalized" (1; #1),
#  "GrayLevelVariance" (1; #2),
#  "HighGrayLevelZoneEmphasis" (1; #3),
#  "LargeAreaEmphasis" (1; #4),
#  "LargeAreaHighGrayLevelEmphasis" (1; #5),
#  "LargeAreaLowGrayLevelEmphasis" (1; #6),
#  "LowGrayLevelZoneEmphasis" (1; #7),
#  "SizeZoneNonUniformity" (1; #8),
#  "SizeZoneNonUniformityNormalized" (1; #9),
#  "SmallAreaEmphasis" (1; #10),
#  "SmallAreaHighGrayLevelEmphasis" (1; #11),
#  "SmallAreaLowGrayLevelEmphasis" (1; #12),
#  "ZoneEntropy" (1; #13),
#  "ZonePercentage" (1; #14),
#  "ZoneVariance" (1; #15)]

# %%
# Feature importance
model.make_inspector().variable_importances()
# Out:
# {'INV_MEAN_MIN_DEPTH': [("HighGrayLevelZoneEmphasis" (1; #3),
#    0.3326859583221464),
#   ("SmallAreaHighGrayLevelEmphasis" (1; #11), 0.28949094517894486),
#   ("LowGrayLevelZoneEmphasis" (1; #7), 0.2655220800455795),
#   ("LargeAreaLowGrayLevelEmphasis" (1; #6), 0.23945521197672368),
#   ("SmallAreaLowGrayLevelEmphasis" (1; #12), 0.23629126999316027),
#   ("GrayLevelNonUniformity" (1; #0), 0.22531515856292794),
#   ("GrayLevelNonUniformityNormalized" (1; #1), 0.2241793445412509),
#   ("ZoneEntropy" (1; #13), 0.22090592441224707),
#   ("GrayLevelVariance" (1; #2), 0.21192736590536407),
#   ("ZoneVariance" (1; #15), 0.20528754276629513),
#   ("LargeAreaEmphasis" (1; #4), 0.20339742589174675),
#   ("LargeAreaHighGrayLevelEmphasis" (1; #5), 0.20117919902231504),
#   ("ZonePercentage" (1; #14), 0.19941581563908953),
#   ("SizeZoneNonUniformityNormalized" (1; #9), 0.19906171304997589),
#   ("SmallAreaEmphasis" (1; #10), 0.19810084273030942),
#   ("SizeZoneNonUniformity" (1; #8), 0.19759841447497387)],
#  'SUM_SCORE': [("HighGrayLevelZoneEmphasis" (1; #3), 104762.51282955652),
#   ("SmallAreaHighGrayLevelEmphasis" (1; #11), 72738.27944691273),
#   ("LowGrayLevelZoneEmphasis" (1; #7), 47110.99464953822),
#   ("SmallAreaLowGrayLevelEmphasis" (1; #12), 28341.474137165445),
#   ("LargeAreaLowGrayLevelEmphasis" (1; #6), 15965.809676490377),
#   ("ZoneEntropy" (1; #13), 15376.910038124515),
#   ("GrayLevelNonUniformityNormalized" (1; #1), 10255.25779075234),
#   ("GrayLevelNonUniformity" (1; #0), 6400.264150223542),
#   ("GrayLevelVariance" (1; #2), 5503.834408002599),
#   ("ZoneVariance" (1; #15), 3288.5704858655895),
#   ("LargeAreaEmphasis" (1; #4), 2696.847857048127),
#   ("ZonePercentage" (1; #14), 1580.0210581664974),
#   ("LargeAreaHighGrayLevelEmphasis" (1; #5), 1479.909918273648),
#   ("SizeZoneNonUniformityNormalized" (1; #9), 795.504996259271),
#   ("SizeZoneNonUniformity" (1; #8), 550.2252756443321),
#   ("SmallAreaEmphasis" (1; #10), 435.59700828280995)],
#  'NUM_AS_ROOT': [("HighGrayLevelZoneEmphasis" (1; #3), 90.0),
#   ("SmallAreaHighGrayLevelEmphasis" (1; #11), 64.0),
#   ("LowGrayLevelZoneEmphasis" (1; #7), 56.0),
#   ("SmallAreaLowGrayLevelEmphasis" (1; #12), 40.0),
#   ("LargeAreaLowGrayLevelEmphasis" (1; #6), 21.0),
#   ("ZoneEntropy" (1; #13), 12.0),
#   ("GrayLevelNonUniformityNormalized" (1; #1), 11.0),
#   ("GrayLevelVariance" (1; #2), 5.0),
#   ("LargeAreaEmphasis" (1; #4), 1.0)],
#  'NUM_NODES': [("HighGrayLevelZoneEmphasis" (1; #3), 488.0),
#   ("SmallAreaHighGrayLevelEmphasis" (1; #11), 331.0),
#   ("LargeAreaLowGrayLevelEmphasis" (1; #6), 298.0),
#   ("LowGrayLevelZoneEmphasis" (1; #7), 295.0),
#   ("GrayLevelNonUniformity" (1; #0), 286.0),
#   ("ZoneEntropy" (1; #13), 272.0),
#   ("GrayLevelNonUniformityNormalized" (1; #1), 233.0),
#   ("SmallAreaLowGrayLevelEmphasis" (1; #12), 206.0),
#   ("GrayLevelVariance" (1; #2), 148.0),
#   ("ZoneVariance" (1; #15), 143.0),
#   ("LargeAreaEmphasis" (1; #4), 138.0),
#   ("LargeAreaHighGrayLevelEmphasis" (1; #5), 90.0),
#   ("ZonePercentage" (1; #14), 81.0),
#   ("SizeZoneNonUniformityNormalized" (1; #9), 80.0),
#   ("SmallAreaEmphasis" (1; #10), 69.0),
#   ("SizeZoneNonUniformity" (1; #8), 52.0)]}

# %%
# Model self evaluation
model.make_inspector().evaluation()
# Out:
# Evaluation(num_examples=1554, accuracy=0.9625936102188284, loss=0.07737726287688645, rmse=None, ndcg=None, aucs=None, auuc=None, qini=None)

# %%
logs = model.make_inspector().training_logs()

plt.figure(figsize=(12, 4))
plt.subplot(1, 2, 1)
plt.plot([log.num_trees for log in logs], [log.evaluation.accuracy for log in logs])
plt.xlabel("Number of trees")
plt.ylabel("Accuracy (out-of-bag)")
plt.subplot(1, 2, 2)
plt.plot([log.num_trees for log in logs], [log.evaluation.loss for log in logs])
plt.xlabel("Number of trees")
plt.ylabel("Logloss (out-of-bag)")
plt.show()

# %% [markdown]
# Calculate the score of our hold-out validation dataset

# %%
predictions = model.predict(val_ds)
y_true      = validation_data["label"]

from sklearn.metrics import roc_auc_score
ROC_AUC = roc_auc_score(y_true, predictions)
print("The ROC AUC score is %.5f" % ROC_AUC )
# Out:
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 60ms/step
# The ROC AUC score is 0.99799

# %%
# Compute binary classification metrics with sklearn
import numpy as np
from sklearn.metrics import (
    accuracy_score,
    precision_score,
    recall_score,
    f1_score,
    roc_auc_score,
    average_precision_score,
    confusion_matrix,
    classification_report,
    matthews_corrcoef,
    log_loss,
    brier_score_loss,
)

# Get predictions (probabilities or class labels)
preds = model.predict(test_ds)
# If model outputs probabilities, convert to labels by threshold 0.5
if preds.ndim == 2:
    # For TFDF classification, preds may be class probabilities with shape (N, 2)
    if preds.shape[1] == 2:
        pos_probs = preds[:, 1]
    else:
        # If single-probability column (positive class)
        pos_probs = preds[:, -1]
    y_pred = (pos_probs >= 0.5).astype(int)
else:
    # Already class labels
    y_pred = preds.astype(int)
    pos_probs = None

# Ground truth labels (must be 0/1 integers)
y_true = test_data["label"].astype(int).to_numpy()

# Core metrics
metrics = {}
metrics["accuracy"] = accuracy_score(y_true, y_pred)
metrics["precision"] = precision_score(y_true, y_pred, zero_division=0)
metrics["recall"] = recall_score(y_true, y_pred, zero_division=0)
metrics["f1"] = f1_score(y_true, y_pred, zero_division=0)
metrics["mcc"] = matthews_corrcoef(y_true, y_pred)

# Probabilistic metrics (only if we have probabilities)
if pos_probs is not None:
    metrics["roc_auc"] = roc_auc_score(y_true, pos_probs)
    metrics["pr_auc"] = average_precision_score(y_true, pos_probs)
    metrics["log_loss"] = log_loss(y_true, pos_probs, labels=[0,1])
    metrics["brier_score"] = brier_score_loss(y_true, pos_probs)

# Confusion matrix and detailed report
cm = confusion_matrix(y_true, y_pred, labels=[0,1])
report = classification_report(y_true, y_pred, digits=4)

print("Sklearn binary metrics:")
for k, v in metrics.items():
    print(f"{k}: {v:.4f}")
print("\nConfusion matrix:\n", cm)
print("\nClassification report:\n", report)
# Out:
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 85ms/step
# Sklearn binary metrics:
# accuracy: 0.9797
# precision: 0.7500
# recall: 0.8571
# f1: 0.8000
# mcc: 0.7913
# roc_auc: 0.9958
# pr_auc: 0.9424
# log_loss: 0.0380
# brier_score: 0.0121
#
# Confusion matrix:
#  [[417   6]
#  [  3  18]]
#
# Classification report:
#                precision    recall  f1-score   support
#
#            0     0.9929    0.9858    0.9893       423
#            1     0.7500    0.8571    0.8000        21
#
#     accuracy                         0.9797       444
#    macro avg     0.8714    0.9215    0.8947       444
# weighted avg     0.9814    0.9797    0.9804       444
