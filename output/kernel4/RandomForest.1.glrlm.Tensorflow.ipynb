# %%
# Import packages and modules
import numpy  as np
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow_decision_forests as tfdf

from sklearn.model_selection import train_test_split
# Out:
# 2026-08-15 05:14:28.435045: I tensorflow/core/util/port.cc:113] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2026-08-15 05:14:28.796787: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2026-08-15 05:14:34.292075: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
# Check the version of TensorFlow Decision Forests
print("Found TensorFlow Decision Forests v" + tfdf.__version__)
# Out:
# Found TensorFlow Decision Forests v1.9.1

# %%
datasetPath = 'dataset/firstorder/kernel5/dataset.csv'

# %%
# Parameters
datasetPath = "dataset/glrlm/kernel4/1.dataset.csv"

# %%
# train/validation/test = 70/10/20
dataset = pd.read_csv(datasetPath)

train_data, temp_data = train_test_split(dataset, test_size=0.3, random_state=42)
validation_data, test_data = train_test_split(temp_data, test_size=2/3, random_state=42)

# %%
from sklearn.utils.class_weight import compute_class_weight

# tinh class weight tren tap train
classes = np.array([0, 1])
weights = compute_class_weight(class_weight="balanced", classes=classes, y=train_data["label"])
class_weight = {0: weights[0], 1: weights[1]}

# gan sample_weight cho tung dong
train_data["sample_weight"] = train_data["label"].map(class_weight)
validation_data["sample_weight"] = validation_data["label"].map(class_weight)
test_data["sample_weight"] = test_data["label"].map(class_weight)

# Convert the dataset into a TensorFlow dataset.
train_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    train_data, label="label", weight="sample_weight"
)         
val_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    validation_data, label="label", weight="sample_weight"
)
test_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    test_data, label="label", weight="sample_weight"
)
# Out:
# 2026-08-15 05:14:47.418402: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:984] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2026-08-15 05:14:47.420241: W tensorflow/core/common_runtime/gpu/gpu_device.cc:2251] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...

# %%
import keras

# %%
# %%time

# Train a Random Forest model.
model = tfdf.keras.RandomForestModel()

# Add evaluation metrics
model.compile(
    metrics=["accuracy"]
)
model.fit(x=train_ds)

# # Train a Gradient Boosted Trees model.
# model = tfdf.keras.GradientBoostedTreesModel(num_trees=1500)
# model.fit(train_ds)
# Out:
# Use /tmp/tmpdmql8xjr as temporary training directory
# Reading training dataset...
# Training dataset read in 0:00:02.592974. Found 1554 examples.
# Training model...
# Model trained in 0:00:00.070637
# Compiling model...
# [INFO 26-08-15 05:14:50.2471 UTC kernel.cc:1233] Loading model from path /tmp/tmpdmql8xjr/model/ with prefix 56d76d753f3846f9
# [INFO 26-08-15 05:14:50.2563 UTC decision_forest.cc:734] Model loaded with 300 root(s), 7244 node(s), and 16 input feature(s).
# [INFO 26-08-15 05:14:50.2563 UTC abstract_model.cc:1362] Engine "RandomForestOptPred" built
# [INFO 26-08-15 05:14:50.2563 UTC kernel.cc:1061] Use fast generic engine
# Model compiled.
# CPU times: user 5.61 s, sys: 80 ms, total: 5.69 s
# Wall time: 5.84 s

# %%
# Evaluate the model
evaluate = model.evaluate(val_ds, return_dict=True)
print()

for name, value in evaluate.items():
    print(f"{name}: {value:.4f}")
# Out:
# WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 1/1 [==============================] - ETA: 0s - loss: 0.0000e+00 - accuracy: 0.9955
# 1/1 [==============================] - 3s 3s/step - loss: 0.0000e+00 - accuracy: 0.9955
# loss: 0.0000
# accuracy: 0.9955

# %%
# Model Summary
model.summary()
# Out:
# Model: "random_forest_model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
# =================================================================
# Total params: 1 (1.00 Byte)
# Trainable params: 0 (0.00 Byte)
# Non-trainable params: 1 (1.00 Byte)
# _________________________________________________________________
# Type: "RANDOM_FOREST"
# Task: CLASSIFICATION
# Label: "__LABEL"
#
# Input Features (16):
# 	GrayLevelNonUniformity
# 	GrayLevelNonUniformityNormalized
# 	GrayLevelVariance
# 	HighGrayLevelRunEmphasis
# 	LongRunEmphasis
# 	LongRunHighGrayLevelEmphasis
# 	LongRunLowGrayLevelEmphasis
# 	LowGrayLevelRunEmphasis
# 	RunEntropy
# 	RunLengthNonUniformity
# 	RunLengthNonUniformityNormalized
# 	RunPercentage
# 	RunVariance
# 	ShortRunEmphasis
# 	ShortRunHighGrayLevelEmphasis
# 	ShortRunLowGrayLevelEmphasis
#
# Trained with weights
#
# Variable Importance: INV_MEAN_MIN_DEPTH:
#     1.    "ShortRunHighGrayLevelEmphasis"  0.311484 ################
#     2.         "HighGrayLevelRunEmphasis"  0.275031 ##########
#     3.     "LongRunHighGrayLevelEmphasis"  0.248455 #######
#     4.      "LongRunLowGrayLevelEmphasis"  0.241647 ######
#     5. "GrayLevelNonUniformityNormalized"  0.231930 ####
#     6.          "LowGrayLevelRunEmphasis"  0.231441 ####
#     7.           "GrayLevelNonUniformity"  0.225038 ####
#     8.     "ShortRunLowGrayLevelEmphasis"  0.221369 ###
#     9.                       "RunEntropy"  0.220314 ###
#    10.                "GrayLevelVariance"  0.210634 ##
#    11.                      "RunVariance"  0.200769
#    12. "RunLengthNonUniformityNormalized"  0.200667
#    13.                 "ShortRunEmphasis"  0.199629
#    14.           "RunLengthNonUniformity"  0.198480
#    15.                  "LongRunEmphasis"  0.197297
#    16.                    "RunPercentage"  0.196180
#
# Variable Importance: NUM_AS_ROOT:
#     1.    "ShortRunHighGrayLevelEmphasis" 94.000000 ################
#     2.         "HighGrayLevelRunEmphasis" 60.000000 ##########
#     3.     "LongRunHighGrayLevelEmphasis" 48.000000 ########
#     4.      "LongRunLowGrayLevelEmphasis" 46.000000 #######
#     5.          "LowGrayLevelRunEmphasis" 26.000000 ####
#     6.     "ShortRunLowGrayLevelEmphasis" 14.000000 ##
#     7. "GrayLevelNonUniformityNormalized"  7.000000 #
#     8.           "GrayLevelNonUniformity"  4.000000
#     9.                      "RunVariance"  1.000000
#
# Variable Importance: NUM_NODES:
#     1.    "ShortRunHighGrayLevelEmphasis" 384.000000 ################
#     2.         "HighGrayLevelRunEmphasis" 327.000000 #############
#     3. "GrayLevelNonUniformityNormalized" 311.000000 ############
#     4.      "LongRunLowGrayLevelEmphasis" 294.000000 ###########
#     5.     "LongRunHighGrayLevelEmphasis" 286.000000 ##########
#     6.          "LowGrayLevelRunEmphasis" 286.000000 ##########
#     7.           "GrayLevelNonUniformity" 270.000000 ##########
#     8.                       "RunEntropy" 261.000000 #########
#     9.     "ShortRunLowGrayLevelEmphasis" 255.000000 #########
#    10.                "GrayLevelVariance" 219.000000 #######
#    11. "RunLengthNonUniformityNormalized" 116.000000 ##
#    12.                      "RunVariance" 111.000000 ##
#    13.                 "ShortRunEmphasis" 102.000000 #
#    14.           "RunLengthNonUniformity" 100.000000 #
#    15.                    "RunPercentage" 78.000000
#    16.                  "LongRunEmphasis" 72.000000
#
# Variable Importance: SUM_SCORE:
#     1.    "ShortRunHighGrayLevelEmphasis" 84761.609961 ################
#     2.         "HighGrayLevelRunEmphasis" 56970.018209 ##########
#     3.     "LongRunHighGrayLevelEmphasis" 42002.907210 #######
#     4.      "LongRunLowGrayLevelEmphasis" 35231.092433 ######
#     5.          "LowGrayLevelRunEmphasis" 22799.816180 ####
#     6. "GrayLevelNonUniformityNormalized" 17602.438322 ###
#     7.           "GrayLevelNonUniformity" 15846.791894 ##
#     8.     "ShortRunLowGrayLevelEmphasis" 14833.473261 ##
#     9.                       "RunEntropy" 10893.239911 #
#    10.                "GrayLevelVariance" 4771.557381
#    11.                 "ShortRunEmphasis" 2156.279390
#    12. "RunLengthNonUniformityNormalized" 2146.339099
#    13.                      "RunVariance" 1663.999936
#    14.           "RunLengthNonUniformity" 1501.562445
#    15.                  "LongRunEmphasis" 1065.560871
#    16.                    "RunPercentage" 718.040136
#
#
#
# Winner takes all: true
# Out-of-bag evaluation: accuracy:0.97028 logloss:0.121033
# Number of trees: 300
# Total number of nodes: 7244
#
# Number of nodes by tree:
# Count: 300 Average: 24.1467 StdDev: 3.81119
# Min: 15 Max: 37 Ignored: 0
# ----------------------------------------------
# [ 15, 16)  4   1.33%   1.33% #
# [ 16, 17)  0   0.00%   1.33%
# [ 17, 18)  5   1.67%   3.00% #
# [ 18, 19)  0   0.00%   3.00%
# [ 19, 20) 31  10.33%  13.33% #####
# [ 20, 21)  0   0.00%  13.33%
# [ 21, 23) 51  17.00%  30.33% ########
# [ 23, 24) 58  19.33%  49.67% #########
# [ 24, 25)  0   0.00%  49.67%
# [ 25, 26) 62  20.67%  70.33% ##########
# [ 26, 27)  0   0.00%  70.33%
# [ 27, 28) 47  15.67%  86.00% ########
# [ 28, 29)  0   0.00%  86.00%
# [ 29, 31) 21   7.00%  93.00% ###
# [ 31, 32) 13   4.33%  97.33% ##
# [ 32, 33)  0   0.00%  97.33%
# [ 33, 34)  4   1.33%  98.67% #
# [ 34, 35)  0   0.00%  98.67%
# [ 35, 36)  3   1.00%  99.67%
# [ 36, 37]  1   0.33% 100.00%
#
# Depth by leafs:
# Count: 3772 Average: 4.21023 StdDev: 1.35292
# Min: 1 Max: 9 Ignored: 0
# ----------------------------------------------
# [ 1, 2)    7   0.19%   0.19%
# [ 2, 3)  347   9.20%   9.38% ###
# [ 3, 4)  872  23.12%  32.50% ########
# [ 4, 5) 1061  28.13%  60.63% ##########
# [ 5, 6)  821  21.77%  82.40% ########
# [ 6, 7)  483  12.80%  95.20% #####
# [ 7, 8)  139   3.69%  98.89% #
# [ 8, 9)   34   0.90%  99.79%
# [ 9, 9]    8   0.21% 100.00%
#
# Number of training obs by leaf:
# Count: 3772 Average: 123.595 StdDev: 336.584
# Min: 5 Max: 1395 Ignored: 0
# ----------------------------------------------
# [    5,   74) 3160  83.78%  83.78% ##########
# [   74,  144)  262   6.95%  90.72% #
# [  144,  213)   21   0.56%  91.28%
# [  213,  283)   12   0.32%  91.60%
# [  283,  352)    9   0.24%  91.83%
# [  352,  422)    4   0.11%  91.94%
# [  422,  491)    1   0.03%  91.97%
# [  491,  561)    2   0.05%  92.02%
# [  561,  630)    1   0.03%  92.05%
# [  630,  700)    0   0.00%  92.05%
# [  700,  770)    1   0.03%  92.07%
# [  770,  839)    2   0.05%  92.13%
# [  839,  909)    1   0.03%  92.15%
# [  909,  978)    1   0.03%  92.18%
# [  978, 1048)   10   0.27%  92.44%
# [ 1048, 1117)   12   0.32%  92.76%
# [ 1117, 1187)   25   0.66%  93.43%
# [ 1187, 1256)   55   1.46%  94.88%
# [ 1256, 1326)  132   3.50%  98.38%
# [ 1326, 1395]   61   1.62% 100.00%
#
# Attribute in nodes:
# 	384 : ShortRunHighGrayLevelEmphasis [NUMERICAL]
# 	327 : HighGrayLevelRunEmphasis [NUMERICAL]
# 	311 : GrayLevelNonUniformityNormalized [NUMERICAL]
# 	294 : LongRunLowGrayLevelEmphasis [NUMERICAL]
# 	286 : LowGrayLevelRunEmphasis [NUMERICAL]
# 	286 : LongRunHighGrayLevelEmphasis [NUMERICAL]
# 	270 : GrayLevelNonUniformity [NUMERICAL]
# 	261 : RunEntropy [NUMERICAL]
# 	255 : ShortRunLowGrayLevelEmphasis [NUMERICAL]
# 	219 : GrayLevelVariance [NUMERICAL]
# 	116 : RunLengthNonUniformityNormalized [NUMERICAL]
# 	111 : RunVariance [NUMERICAL]
# 	102 : ShortRunEmphasis [NUMERICAL]
# 	100 : RunLengthNonUniformity [NUMERICAL]
# 	78 : RunPercentage [NUMERICAL]
# 	72 : LongRunEmphasis [NUMERICAL]
#
# Attribute in nodes with depth <= 0:
# 	94 : ShortRunHighGrayLevelEmphasis [NUMERICAL]
# 	60 : HighGrayLevelRunEmphasis [NUMERICAL]
# 	48 : LongRunHighGrayLevelEmphasis [NUMERICAL]
# 	46 : LongRunLowGrayLevelEmphasis [NUMERICAL]
# 	26 : LowGrayLevelRunEmphasis [NUMERICAL]
# 	14 : ShortRunLowGrayLevelEmphasis [NUMERICAL]
# 	7 : GrayLevelNonUniformityNormalized [NUMERICAL]
# 	4 : GrayLevelNonUniformity [NUMERICAL]
# 	1 : RunVariance [NUMERICAL]
#
# Attribute in nodes with depth <= 1:
# 	206 : ShortRunHighGrayLevelEmphasis [NUMERICAL]
# 	155 : HighGrayLevelRunEmphasis [NUMERICAL]
# 	108 : LongRunHighGrayLevelEmphasis [NUMERICAL]
# 	90 : GrayLevelNonUniformityNormalized [NUMERICAL]
# 	79 : GrayLevelNonUniformity [NUMERICAL]
# 	60 : LongRunLowGrayLevelEmphasis [NUMERICAL]
# 	48 : LowGrayLevelRunEmphasis [NUMERICAL]
# 	46 : RunEntropy [NUMERICAL]
# 	33 : ShortRunLowGrayLevelEmphasis [NUMERICAL]
# 	20 : RunLengthNonUniformityNormalized [NUMERICAL]
# 	12 : ShortRunEmphasis [NUMERICAL]
# 	12 : RunLengthNonUniformity [NUMERICAL]
# 	12 : GrayLevelVariance [NUMERICAL]
# 	5 : RunVariance [NUMERICAL]
# 	5 : LongRunEmphasis [NUMERICAL]
# 	2 : RunPercentage [NUMERICAL]
#
# Attribute in nodes with depth <= 2:
# 	284 : ShortRunHighGrayLevelEmphasis [NUMERICAL]
# 	234 : HighGrayLevelRunEmphasis [NUMERICAL]
# 	174 : GrayLevelNonUniformityNormalized [NUMERICAL]
# 	171 : LongRunHighGrayLevelEmphasis [NUMERICAL]
# 	151 : GrayLevelNonUniformity [NUMERICAL]
# 	143 : LongRunLowGrayLevelEmphasis [NUMERICAL]
# 	132 : LowGrayLevelRunEmphasis [NUMERICAL]
# 	131 : RunEntropy [NUMERICAL]
# 	108 : ShortRunLowGrayLevelEmphasis [NUMERICAL]
# 	74 : GrayLevelVariance [NUMERICAL]
# 	29 : RunLengthNonUniformityNormalized [NUMERICAL]
# 	27 : RunVariance [NUMERICAL]
# 	26 : ShortRunEmphasis [NUMERICAL]
# 	19 : RunLengthNonUniformity [NUMERICAL]
# 	18 : LongRunEmphasis [NUMERICAL]
# 	11 : RunPercentage [NUMERICAL]
#
# Attribute in nodes with depth <= 3:
# 	333 : ShortRunHighGrayLevelEmphasis [NUMERICAL]
# 	279 : HighGrayLevelRunEmphasis [NUMERICAL]
# 	238 : GrayLevelNonUniformityNormalized [NUMERICAL]
# 	227 : LowGrayLevelRunEmphasis [NUMERICAL]
# 	227 : LongRunHighGrayLevelEmphasis [NUMERICAL]
# 	226 : LongRunLowGrayLevelEmphasis [NUMERICAL]
# 	193 : GrayLevelNonUniformity [NUMERICAL]
# 	191 : ShortRunLowGrayLevelEmphasis [NUMERICAL]
# 	190 : RunEntropy [NUMERICAL]
# 	144 : GrayLevelVariance [NUMERICAL]
# 	58 : RunLengthNonUniformityNormalized [NUMERICAL]
# 	56 : RunVariance [NUMERICAL]
# 	55 : ShortRunEmphasis [NUMERICAL]
# 	44 : RunLengthNonUniformity [NUMERICAL]
# 	41 : LongRunEmphasis [NUMERICAL]
# 	36 : RunPercentage [NUMERICAL]
#
# Attribute in nodes with depth <= 5:
# 	380 : ShortRunHighGrayLevelEmphasis [NUMERICAL]
# 	321 : HighGrayLevelRunEmphasis [NUMERICAL]
# 	302 : GrayLevelNonUniformityNormalized [NUMERICAL]
# 	291 : LongRunLowGrayLevelEmphasis [NUMERICAL]
# 	282 : LowGrayLevelRunEmphasis [NUMERICAL]
# 	276 : LongRunHighGrayLevelEmphasis [NUMERICAL]
# 	260 : GrayLevelNonUniformity [NUMERICAL]
# 	255 : RunEntropy [NUMERICAL]
# 	248 : ShortRunLowGrayLevelEmphasis [NUMERICAL]
# 	211 : GrayLevelVariance [NUMERICAL]
# 	112 : RunLengthNonUniformityNormalized [NUMERICAL]
# 	100 : RunVariance [NUMERICAL]
# 	93 : ShortRunEmphasis [NUMERICAL]
# 	93 : RunLengthNonUniformity [NUMERICAL]
# 	77 : RunPercentage [NUMERICAL]
# 	69 : LongRunEmphasis [NUMERICAL]
#
# Condition type in nodes:
# 	3472 : HigherCondition
# Condition type in nodes with depth <= 0:
# 	300 : HigherCondition
# Condition type in nodes with depth <= 1:
# 	893 : HigherCondition
# Condition type in nodes with depth <= 2:
# 	1732 : HigherCondition
# Condition type in nodes with depth <= 3:
# 	2538 : HigherCondition
# Condition type in nodes with depth <= 5:
# 	3370 : HigherCondition
# Node format: NOT_SET
#
# Training OOB:
# 	trees: 1, Out-of-bag evaluation: accuracy:0.940751 logloss:2.13555
# 	trees: 13, Out-of-bag evaluation: accuracy:0.945048 logloss:1.13332
# 	trees: 24, Out-of-bag evaluation: accuracy:0.955801 logloss:0.805547
# 	trees: 34, Out-of-bag evaluation: accuracy:0.960179 logloss:0.616715
# 	trees: 44, Out-of-bag evaluation: accuracy:0.960179 logloss:0.617537
# 	trees: 55, Out-of-bag evaluation: accuracy:0.96523 logloss:0.615104
# 	trees: 66, Out-of-bag evaluation: accuracy:0.965573 logloss:0.615305
# 	trees: 76, Out-of-bag evaluation: accuracy:0.96523 logloss:0.615839
# 	trees: 87, Out-of-bag evaluation: accuracy:0.960179 logloss:0.615609
# 	trees: 97, Out-of-bag evaluation: accuracy:0.960179 logloss:0.123045
# 	trees: 107, Out-of-bag evaluation: accuracy:0.96523 logloss:0.125001
# 	trees: 117, Out-of-bag evaluation: accuracy:0.96523 logloss:0.122875
# 	trees: 130, Out-of-bag evaluation: accuracy:0.96523 logloss:0.125967
# 	trees: 140, Out-of-bag evaluation: accuracy:0.96523 logloss:0.122865
# 	trees: 152, Out-of-bag evaluation: accuracy:0.965573 logloss:0.120952
# 	trees: 162, Out-of-bag evaluation: accuracy:0.96523 logloss:0.121615
# 	trees: 172, Out-of-bag evaluation: accuracy:0.960179 logloss:0.122903
# 	trees: 183, Out-of-bag evaluation: accuracy:0.96523 logloss:0.120091
# 	trees: 193, Out-of-bag evaluation: accuracy:0.96523 logloss:0.120342
# 	trees: 203, Out-of-bag evaluation: accuracy:0.96523 logloss:0.121039
# 	trees: 213, Out-of-bag evaluation: accuracy:0.955129 logloss:0.122938
# 	trees: 223, Out-of-bag evaluation: accuracy:0.955129 logloss:0.124085
# 	trees: 233, Out-of-bag evaluation: accuracy:0.955129 logloss:0.12324
# 	trees: 243, Out-of-bag evaluation: accuracy:0.955129 logloss:0.124412
# 	trees: 253, Out-of-bag evaluation: accuracy:0.960179 logloss:0.124592
# 	trees: 263, Out-of-bag evaluation: accuracy:0.960179 logloss:0.124947
# 	trees: 275, Out-of-bag evaluation: accuracy:0.960179 logloss:0.124632
# 	trees: 285, Out-of-bag evaluation: accuracy:0.96523 logloss:0.121984
# 	trees: 296, Out-of-bag evaluation: accuracy:0.97028 logloss:0.122366
# 	trees: 300, Out-of-bag evaluation: accuracy:0.97028 logloss:0.121033

# %%
# Model features
model.make_inspector().features()
# Out:
# ["GrayLevelNonUniformity" (1; #0),
#  "GrayLevelNonUniformityNormalized" (1; #1),
#  "GrayLevelVariance" (1; #2),
#  "HighGrayLevelRunEmphasis" (1; #3),
#  "LongRunEmphasis" (1; #4),
#  "LongRunHighGrayLevelEmphasis" (1; #5),
#  "LongRunLowGrayLevelEmphasis" (1; #6),
#  "LowGrayLevelRunEmphasis" (1; #7),
#  "RunEntropy" (1; #8),
#  "RunLengthNonUniformity" (1; #9),
#  "RunLengthNonUniformityNormalized" (1; #10),
#  "RunPercentage" (1; #11),
#  "RunVariance" (1; #12),
#  "ShortRunEmphasis" (1; #13),
#  "ShortRunHighGrayLevelEmphasis" (1; #14),
#  "ShortRunLowGrayLevelEmphasis" (1; #15)]

# %%
# Feature importance
model.make_inspector().variable_importances()
# Out:
# {'INV_MEAN_MIN_DEPTH': [("ShortRunHighGrayLevelEmphasis" (1; #14),
#    0.3114843100557162),
#   ("HighGrayLevelRunEmphasis" (1; #3), 0.2750313689877965),
#   ("LongRunHighGrayLevelEmphasis" (1; #5), 0.24845491880266987),
#   ("LongRunLowGrayLevelEmphasis" (1; #6), 0.24164678328853445),
#   ("GrayLevelNonUniformityNormalized" (1; #1), 0.2319295440844959),
#   ("LowGrayLevelRunEmphasis" (1; #7), 0.2314409959665423),
#   ("GrayLevelNonUniformity" (1; #0), 0.22503804880200004),
#   ("ShortRunLowGrayLevelEmphasis" (1; #15), 0.22136927970878784),
#   ("RunEntropy" (1; #8), 0.22031440602899235),
#   ("GrayLevelVariance" (1; #2), 0.21063442941576488),
#   ("RunVariance" (1; #12), 0.2007686733138303),
#   ("RunLengthNonUniformityNormalized" (1; #10), 0.20066664345413276),
#   ("ShortRunEmphasis" (1; #13), 0.1996293749532749),
#   ("RunLengthNonUniformity" (1; #9), 0.19847965976467968),
#   ("LongRunEmphasis" (1; #4), 0.19729704049179203),
#   ("RunPercentage" (1; #11), 0.19618044818173003)],
#  'NUM_AS_ROOT': [("ShortRunHighGrayLevelEmphasis" (1; #14), 94.0),
#   ("HighGrayLevelRunEmphasis" (1; #3), 60.0),
#   ("LongRunHighGrayLevelEmphasis" (1; #5), 48.0),
#   ("LongRunLowGrayLevelEmphasis" (1; #6), 46.0),
#   ("LowGrayLevelRunEmphasis" (1; #7), 26.0),
#   ("ShortRunLowGrayLevelEmphasis" (1; #15), 14.0),
#   ("GrayLevelNonUniformityNormalized" (1; #1), 7.0),
#   ("GrayLevelNonUniformity" (1; #0), 4.0),
#   ("RunVariance" (1; #12), 1.0)],
#  'SUM_SCORE': [("ShortRunHighGrayLevelEmphasis" (1; #14), 84761.6099613876),
#   ("HighGrayLevelRunEmphasis" (1; #3), 56970.01820913772),
#   ("LongRunHighGrayLevelEmphasis" (1; #5), 42002.9072096846),
#   ("LongRunLowGrayLevelEmphasis" (1; #6), 35231.09243274583),
#   ("LowGrayLevelRunEmphasis" (1; #7), 22799.816179666566),
#   ("GrayLevelNonUniformityNormalized" (1; #1), 17602.43832167795),
#   ("GrayLevelNonUniformity" (1; #0), 15846.791894089922),
#   ("ShortRunLowGrayLevelEmphasis" (1; #15), 14833.473260945879),
#   ("RunEntropy" (1; #8), 10893.23991147851),
#   ("GrayLevelVariance" (1; #2), 4771.557381221808),
#   ("ShortRunEmphasis" (1; #13), 2156.2793899146545),
#   ("RunLengthNonUniformityNormalized" (1; #10), 2146.3390994173),
#   ("RunVariance" (1; #12), 1663.9999362990682),
#   ("RunLengthNonUniformity" (1; #9), 1501.56244484251),
#   ("LongRunEmphasis" (1; #4), 1065.5608708568525),
#   ("RunPercentage" (1; #11), 718.0401357342045)],
#  'NUM_NODES': [("ShortRunHighGrayLevelEmphasis" (1; #14), 384.0),
#   ("HighGrayLevelRunEmphasis" (1; #3), 327.0),
#   ("GrayLevelNonUniformityNormalized" (1; #1), 311.0),
#   ("LongRunLowGrayLevelEmphasis" (1; #6), 294.0),
#   ("LongRunHighGrayLevelEmphasis" (1; #5), 286.0),
#   ("LowGrayLevelRunEmphasis" (1; #7), 286.0),
#   ("GrayLevelNonUniformity" (1; #0), 270.0),
#   ("RunEntropy" (1; #8), 261.0),
#   ("ShortRunLowGrayLevelEmphasis" (1; #15), 255.0),
#   ("GrayLevelVariance" (1; #2), 219.0),
#   ("RunLengthNonUniformityNormalized" (1; #10), 116.0),
#   ("RunVariance" (1; #12), 111.0),
#   ("ShortRunEmphasis" (1; #13), 102.0),
#   ("RunLengthNonUniformity" (1; #9), 100.0),
#   ("RunPercentage" (1; #11), 78.0),
#   ("LongRunEmphasis" (1; #4), 72.0)]}

# %%
# Model self evaluation
model.make_inspector().evaluation()
# Out:
# Evaluation(num_examples=1554, accuracy=0.9702801202957225, loss=0.12103267712740719, rmse=None, ndcg=None, aucs=None, auuc=None, qini=None)

# %%
logs = model.make_inspector().training_logs()

plt.figure(figsize=(12, 4))
plt.subplot(1, 2, 1)
plt.plot([log.num_trees for log in logs], [log.evaluation.accuracy for log in logs])
plt.xlabel("Number of trees")
plt.ylabel("Accuracy (out-of-bag)")
plt.subplot(1, 2, 2)
plt.plot([log.num_trees for log in logs], [log.evaluation.loss for log in logs])
plt.xlabel("Number of trees")
plt.ylabel("Logloss (out-of-bag)")
plt.show()

# %% [markdown]
# Calculate the score of our hold-out validation dataset

# %%
predictions = model.predict(val_ds)
y_true      = validation_data["label"]

from sklearn.metrics import roc_auc_score
ROC_AUC = roc_auc_score(y_true, predictions)
print("The ROC AUC score is %.5f" % ROC_AUC )
# Out:
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 58ms/step
# The ROC AUC score is 1.00000

# %%
# Compute binary classification metrics with sklearn
import numpy as np
from sklearn.metrics import (
    accuracy_score,
    precision_score,
    recall_score,
    f1_score,
    roc_auc_score,
    average_precision_score,
    confusion_matrix,
    classification_report,
    matthews_corrcoef,
    log_loss,
    brier_score_loss,
)

# Get predictions (probabilities or class labels)
preds = model.predict(test_ds)
# If model outputs probabilities, convert to labels by threshold 0.5
if preds.ndim == 2:
    # For TFDF classification, preds may be class probabilities with shape (N, 2)
    if preds.shape[1] == 2:
        pos_probs = preds[:, 1]
    else:
        # If single-probability column (positive class)
        pos_probs = preds[:, -1]
    y_pred = (pos_probs >= 0.5).astype(int)
else:
    # Already class labels
    y_pred = preds.astype(int)
    pos_probs = None

# Ground truth labels (must be 0/1 integers)
y_true = test_data["label"].astype(int).to_numpy()

# Core metrics
metrics = {}
metrics["accuracy"] = accuracy_score(y_true, y_pred)
metrics["precision"] = precision_score(y_true, y_pred, zero_division=0)
metrics["recall"] = recall_score(y_true, y_pred, zero_division=0)
metrics["f1"] = f1_score(y_true, y_pred, zero_division=0)
metrics["mcc"] = matthews_corrcoef(y_true, y_pred)

# Probabilistic metrics (only if we have probabilities)
if pos_probs is not None:
    metrics["roc_auc"] = roc_auc_score(y_true, pos_probs)
    metrics["pr_auc"] = average_precision_score(y_true, pos_probs)
    metrics["log_loss"] = log_loss(y_true, pos_probs, labels=[0,1])
    metrics["brier_score"] = brier_score_loss(y_true, pos_probs)

# Confusion matrix and detailed report
cm = confusion_matrix(y_true, y_pred, labels=[0,1])
report = classification_report(y_true, y_pred, digits=4)

print("Sklearn binary metrics:")
for k, v in metrics.items():
    print(f"{k}: {v:.4f}")
print("\nConfusion matrix:\n", cm)
print("\nClassification report:\n", report)
# Out:
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 68ms/step
# Sklearn binary metrics:
# accuracy: 0.9910
# precision: 0.9032
# recall: 0.9655
# f1: 0.9333
# mcc: 0.9291
# roc_auc: 0.9993
# pr_auc: 0.9908
# log_loss: 0.0210
# brier_score: 0.0060
#
# Confusion matrix:
#  [[412   3]
#  [  1  28]]
#
# Classification report:
#                precision    recall  f1-score   support
#
#            0     0.9976    0.9928    0.9952       415
#            1     0.9032    0.9655    0.9333        29
#
#     accuracy                         0.9910       444
#    macro avg     0.9504    0.9791    0.9643       444
# weighted avg     0.9914    0.9910    0.9911       444
