# %%
# Import packages and modules
import numpy  as np
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow_decision_forests as tfdf

from sklearn.model_selection import train_test_split
# Out:
# 2026-08-12 05:54:58.169077: I tensorflow/core/util/port.cc:113] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2026-08-12 05:54:58.538981: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2026-08-12 05:55:05.891225: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
# Check the version of TensorFlow Decision Forests
print("Found TensorFlow Decision Forests v" + tfdf.__version__)
# Out:
# Found TensorFlow Decision Forests v1.9.1

# %%
datasetPath = 'dataset/firstorder/kernel5-radius5/dataset.csv'

# %%
# Parameters
datasetPath = "dataset/glrlm/kernel4-radius4/1.dataset.csv"

# %%
# train/validation/test = 70/10/20
dataset = pd.read_csv(datasetPath)

train_data, temp_data = train_test_split(dataset, test_size=0.3, random_state=42)
validation_data, test_data = train_test_split(temp_data, test_size=2/3, random_state=42)

# %%
from sklearn.utils.class_weight import compute_class_weight

# tinh class weight tren tap train
classes = np.array([0, 1])
weights = compute_class_weight(class_weight="balanced", classes=classes, y=train_data["label"])
class_weight = {0: weights[0], 1: weights[1]}

# gan sample_weight cho tung dong
train_data["sample_weight"] = train_data["label"].map(class_weight)
validation_data["sample_weight"] = validation_data["label"].map(class_weight)
test_data["sample_weight"] = test_data["label"].map(class_weight)

# Convert the dataset into a TensorFlow dataset.
train_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    train_data, label="label", weight="sample_weight"
)         
val_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    validation_data, label="label", weight="sample_weight"
)
test_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    test_data, label="label", weight="sample_weight"
)
# Out:
# 2026-08-12 05:55:18.520319: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:984] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2026-08-12 05:55:18.522715: W tensorflow/core/common_runtime/gpu/gpu_device.cc:2251] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...

# %%
import keras

# %%
# %%time

# Train a Random Forest model.
model = tfdf.keras.RandomForestModel()

# Add evaluation metrics
model.compile(
    metrics=["accuracy"]
)
model.fit(x=train_ds)

# # Train a Gradient Boosted Trees model.
# model = tfdf.keras.GradientBoostedTreesModel(num_trees=1500)
# model.fit(train_ds)
# Out:
# Use /tmp/tmp7o9nhrhs as temporary training directory
# Reading training dataset...
# Training dataset read in 0:00:02.512275. Found 1336 examples.
# Training model...
# Model trained in 0:00:00.086464
# Compiling model...
# [INFO 26-08-12 05:55:21.2872 UTC kernel.cc:1233] Loading model from path /tmp/tmp7o9nhrhs/model/ with prefix c6eb899f35344fb0
# [INFO 26-08-12 05:55:21.3049 UTC decision_forest.cc:734] Model loaded with 300 root(s), 15968 node(s), and 16 input feature(s).
# [INFO 26-08-12 05:55:21.3049 UTC abstract_model.cc:1362] Engine "RandomForestOptPred" built
# [INFO 26-08-12 05:55:21.3049 UTC kernel.cc:1061] Use fast generic engine
# Model compiled.
# CPU times: user 5.85 s, sys: 99.7 ms, total: 5.95 s
# Wall time: 5.61 s

# %%
# Evaluate the model
evaluate = model.evaluate(val_ds, return_dict=True)
print()

for name, value in evaluate.items():
    print(f"{name}: {value:.4f}")
# Out:
# WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 1/1 [==============================] - ETA: 0s - loss: 0.0000e+00 - accuracy: 0.9529
# 1/1 [==============================] - 3s 3s/step - loss: 0.0000e+00 - accuracy: 0.9529
# loss: 0.0000
# accuracy: 0.9529

# %%
# Model Summary
model.summary()
# Out:
# Model: "random_forest_model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
# =================================================================
# Total params: 1 (1.00 Byte)
# Trainable params: 0 (0.00 Byte)
# Non-trainable params: 1 (1.00 Byte)
# _________________________________________________________________
# Type: "RANDOM_FOREST"
# Task: CLASSIFICATION
# Label: "__LABEL"
#
# Input Features (16):
# 	GrayLevelNonUniformity
# 	GrayLevelNonUniformityNormalized
# 	GrayLevelVariance
# 	HighGrayLevelRunEmphasis
# 	LongRunEmphasis
# 	LongRunHighGrayLevelEmphasis
# 	LongRunLowGrayLevelEmphasis
# 	LowGrayLevelRunEmphasis
# 	RunEntropy
# 	RunLengthNonUniformity
# 	RunLengthNonUniformityNormalized
# 	RunPercentage
# 	RunVariance
# 	ShortRunEmphasis
# 	ShortRunHighGrayLevelEmphasis
# 	ShortRunLowGrayLevelEmphasis
#
# Trained with weights
#
# Variable Importance: INV_MEAN_MIN_DEPTH:
#     1.     "LongRunHighGrayLevelEmphasis"  0.296749 ################
#     2.         "HighGrayLevelRunEmphasis"  0.238854 #########
#     3.    "ShortRunHighGrayLevelEmphasis"  0.205226 #####
#     4.     "ShortRunLowGrayLevelEmphasis"  0.197741 ####
#     5.          "LowGrayLevelRunEmphasis"  0.182459 ###
#     6.      "LongRunLowGrayLevelEmphasis"  0.170550 #
#     7.                       "RunEntropy"  0.165269 #
#     8.                      "RunVariance"  0.164138 #
#     9. "RunLengthNonUniformityNormalized"  0.161442
#    10.                 "ShortRunEmphasis"  0.158558
#    11.                "GrayLevelVariance"  0.158483
#    12.           "RunLengthNonUniformity"  0.158172
#    13.                  "LongRunEmphasis"  0.158039
#    14.                    "RunPercentage"  0.157499
#    15. "GrayLevelNonUniformityNormalized"  0.153437
#    16.           "GrayLevelNonUniformity"  0.152869
#
# Variable Importance: NUM_AS_ROOT:
#     1.  "LongRunHighGrayLevelEmphasis" 89.000000 ################
#     2.      "HighGrayLevelRunEmphasis" 71.000000 ############
#     3. "ShortRunHighGrayLevelEmphasis" 48.000000 ########
#     4.  "ShortRunLowGrayLevelEmphasis" 39.000000 ######
#     5.       "LowGrayLevelRunEmphasis" 20.000000 ###
#     6.   "LongRunLowGrayLevelEmphasis" 18.000000 ###
#     7.                   "RunVariance"  8.000000 #
#     8.               "LongRunEmphasis"  5.000000
#     9.        "RunLengthNonUniformity"  1.000000
#    10.                 "RunPercentage"  1.000000
#
# Variable Importance: NUM_NODES:
#     1.     "LongRunHighGrayLevelEmphasis" 1062.000000 ################
#     2.         "HighGrayLevelRunEmphasis" 708.000000 ########
#     3.    "ShortRunHighGrayLevelEmphasis" 654.000000 #######
#     4.     "ShortRunLowGrayLevelEmphasis" 619.000000 ######
#     5.                       "RunEntropy" 559.000000 #####
#     6.          "LowGrayLevelRunEmphasis" 540.000000 #####
#     7.                "GrayLevelVariance" 476.000000 ###
#     8.      "LongRunLowGrayLevelEmphasis" 459.000000 ###
#     9. "RunLengthNonUniformityNormalized" 389.000000 #
#    10. "GrayLevelNonUniformityNormalized" 385.000000 #
#    11.                 "ShortRunEmphasis" 358.000000 #
#    12.                      "RunVariance" 345.000000
#    13.           "GrayLevelNonUniformity" 338.000000
#    14.           "RunLengthNonUniformity" 335.000000
#    15.                    "RunPercentage" 306.000000
#    16.                  "LongRunEmphasis" 301.000000
#
# Variable Importance: SUM_SCORE:
#     1.     "LongRunHighGrayLevelEmphasis" 78809.751435 ################
#     2.         "HighGrayLevelRunEmphasis" 54991.739099 ##########
#     3.    "ShortRunHighGrayLevelEmphasis" 36618.225475 #######
#     4.     "ShortRunLowGrayLevelEmphasis" 26848.067715 #####
#     5.          "LowGrayLevelRunEmphasis" 16264.615651 ##
#     6.      "LongRunLowGrayLevelEmphasis" 10683.256651 #
#     7.                       "RunEntropy" 6166.401367
#     8.                      "RunVariance" 4539.876925
#     9.                "GrayLevelVariance" 4523.290356
#    10. "RunLengthNonUniformityNormalized" 4295.192806
#    11.                 "ShortRunEmphasis" 3923.370780
#    12.           "RunLengthNonUniformity" 3620.539650
#    13.                  "LongRunEmphasis" 3465.357654
#    14.                    "RunPercentage" 3145.289941
#    15. "GrayLevelNonUniformityNormalized" 3141.598879
#    16.           "GrayLevelNonUniformity" 2888.499063
#
#
#
# Winner takes all: true
# Out-of-bag evaluation: accuracy:0.917385 logloss:0.419736
# Number of trees: 300
# Total number of nodes: 15968
#
# Number of nodes by tree:
# Count: 300 Average: 53.2267 StdDev: 5.75285
# Min: 39 Max: 67 Ignored: 0
# ----------------------------------------------
# [ 39, 40)  2   0.67%   0.67% #
# [ 40, 41)  0   0.00%   0.67%
# [ 41, 43)  8   2.67%   3.33% ##
# [ 43, 44)  7   2.33%   5.67% ##
# [ 44, 46) 20   6.67%  12.33% #####
# [ 46, 47)  0   0.00%  12.33%
# [ 47, 49) 17   5.67%  18.00% ####
# [ 49, 50) 34  11.33%  29.33% #########
# [ 50, 52) 39  13.00%  42.33% ##########
# [ 52, 53)  0   0.00%  42.33%
# [ 53, 54) 33  11.00%  53.33% ########
# [ 54, 56) 40  13.33%  66.67% ##########
# [ 56, 57)  0   0.00%  66.67%
# [ 57, 59) 34  11.33%  78.00% #########
# [ 59, 60) 28   9.33%  87.33% #######
# [ 60, 62) 20   6.67%  94.00% #####
# [ 62, 63)  0   0.00%  94.00%
# [ 63, 65) 12   4.00%  98.00% ###
# [ 65, 66)  5   1.67%  99.67% #
# [ 66, 67]  1   0.33% 100.00%
#
# Depth by leafs:
# Count: 8134 Average: 5.99115 StdDev: 2.09215
# Min: 1 Max: 14 Ignored: 0
# ----------------------------------------------
# [  1,  2)   13   0.16%   0.16%
# [  2,  3)  196   2.41%   2.57% #
# [  3,  4)  678   8.34%  10.90% #####
# [  4,  5) 1228  15.10%  26.00% ########
# [  5,  6) 1485  18.26%  44.26% ##########
# [  6,  7) 1423  17.49%  61.75% ##########
# [  7,  8) 1229  15.11%  76.86% ########
# [  8,  9)  846  10.40%  87.26% ######
# [  9, 10)  555   6.82%  94.09% ####
# [ 10, 11)  303   3.73%  97.81% ##
# [ 11, 12)  129   1.59%  99.40% #
# [ 12, 13)   36   0.44%  99.84%
# [ 13, 14)   11   0.14%  99.98%
# [ 14, 14]    2   0.02% 100.00%
#
# Number of training obs by leaf:
# Count: 8134 Average: 49.2746 StdDev: 132.329
# Min: 5 Max: 1013 Ignored: 0
# ----------------------------------------------
# [    5,   55) 6814  83.77%  83.77% ##########
# [   55,  105)  637   7.83%  91.60% #
# [  105,  156)  178   2.19%  93.79%
# [  156,  206)   77   0.95%  94.74%
# [  206,  257)   44   0.54%  95.28%
# [  257,  307)   30   0.37%  95.65%
# [  307,  358)   29   0.36%  96.00%
# [  358,  408)   22   0.27%  96.27%
# [  408,  459)   27   0.33%  96.61%
# [  459,  509)   19   0.23%  96.84%
# [  509,  559)   29   0.36%  97.20%
# [  559,  610)   39   0.48%  97.68%
# [  610,  660)   42   0.52%  98.19%
# [  660,  711)   27   0.33%  98.52%
# [  711,  761)   26   0.32%  98.84%
# [  761,  812)   40   0.49%  99.34%
# [  812,  862)   29   0.36%  99.69%
# [  862,  913)   18   0.22%  99.91%
# [  913,  963)    5   0.06%  99.98%
# [  963, 1013]    2   0.02% 100.00%
#
# Attribute in nodes:
# 	1062 : LongRunHighGrayLevelEmphasis [NUMERICAL]
# 	708 : HighGrayLevelRunEmphasis [NUMERICAL]
# 	654 : ShortRunHighGrayLevelEmphasis [NUMERICAL]
# 	619 : ShortRunLowGrayLevelEmphasis [NUMERICAL]
# 	559 : RunEntropy [NUMERICAL]
# 	540 : LowGrayLevelRunEmphasis [NUMERICAL]
# 	476 : GrayLevelVariance [NUMERICAL]
# 	459 : LongRunLowGrayLevelEmphasis [NUMERICAL]
# 	389 : RunLengthNonUniformityNormalized [NUMERICAL]
# 	385 : GrayLevelNonUniformityNormalized [NUMERICAL]
# 	358 : ShortRunEmphasis [NUMERICAL]
# 	345 : RunVariance [NUMERICAL]
# 	338 : GrayLevelNonUniformity [NUMERICAL]
# 	335 : RunLengthNonUniformity [NUMERICAL]
# 	306 : RunPercentage [NUMERICAL]
# 	301 : LongRunEmphasis [NUMERICAL]
#
# Attribute in nodes with depth <= 0:
# 	89 : LongRunHighGrayLevelEmphasis [NUMERICAL]
# 	71 : HighGrayLevelRunEmphasis [NUMERICAL]
# 	48 : ShortRunHighGrayLevelEmphasis [NUMERICAL]
# 	39 : ShortRunLowGrayLevelEmphasis [NUMERICAL]
# 	20 : LowGrayLevelRunEmphasis [NUMERICAL]
# 	18 : LongRunLowGrayLevelEmphasis [NUMERICAL]
# 	8 : RunVariance [NUMERICAL]
# 	5 : LongRunEmphasis [NUMERICAL]
# 	1 : RunPercentage [NUMERICAL]
# 	1 : RunLengthNonUniformity [NUMERICAL]
#
# Attribute in nodes with depth <= 1:
# 	243 : LongRunHighGrayLevelEmphasis [NUMERICAL]
# 	185 : HighGrayLevelRunEmphasis [NUMERICAL]
# 	122 : ShortRunHighGrayLevelEmphasis [NUMERICAL]
# 	107 : ShortRunLowGrayLevelEmphasis [NUMERICAL]
# 	90 : LowGrayLevelRunEmphasis [NUMERICAL]
# 	45 : LongRunLowGrayLevelEmphasis [NUMERICAL]
# 	18 : RunVariance [NUMERICAL]
# 	18 : RunEntropy [NUMERICAL]
# 	10 : RunPercentage [NUMERICAL]
# 	10 : LongRunEmphasis [NUMERICAL]
# 	9 : ShortRunEmphasis [NUMERICAL]
# 	8 : GrayLevelVariance [NUMERICAL]
# 	7 : RunLengthNonUniformity [NUMERICAL]
# 	6 : RunLengthNonUniformityNormalized [NUMERICAL]
# 	5 : GrayLevelNonUniformity [NUMERICAL]
# 	4 : GrayLevelNonUniformityNormalized [NUMERICAL]
#
# Attribute in nodes with depth <= 2:
# 	427 : LongRunHighGrayLevelEmphasis [NUMERICAL]
# 	272 : HighGrayLevelRunEmphasis [NUMERICAL]
# 	189 : ShortRunLowGrayLevelEmphasis [NUMERICAL]
# 	187 : ShortRunHighGrayLevelEmphasis [NUMERICAL]
# 	147 : LowGrayLevelRunEmphasis [NUMERICAL]
# 	81 : LongRunLowGrayLevelEmphasis [NUMERICAL]
# 	79 : RunEntropy [NUMERICAL]
# 	73 : RunLengthNonUniformityNormalized [NUMERICAL]
# 	71 : RunVariance [NUMERICAL]
# 	61 : GrayLevelVariance [NUMERICAL]
# 	57 : ShortRunEmphasis [NUMERICAL]
# 	56 : RunLengthNonUniformity [NUMERICAL]
# 	53 : LongRunEmphasis [NUMERICAL]
# 	51 : RunPercentage [NUMERICAL]
# 	35 : GrayLevelNonUniformityNormalized [NUMERICAL]
# 	26 : GrayLevelNonUniformity [NUMERICAL]
#
# Attribute in nodes with depth <= 3:
# 	595 : LongRunHighGrayLevelEmphasis [NUMERICAL]
# 	355 : HighGrayLevelRunEmphasis [NUMERICAL]
# 	305 : ShortRunHighGrayLevelEmphasis [NUMERICAL]
# 	266 : ShortRunLowGrayLevelEmphasis [NUMERICAL]
# 	224 : LowGrayLevelRunEmphasis [NUMERICAL]
# 	188 : RunEntropy [NUMERICAL]
# 	147 : LongRunLowGrayLevelEmphasis [NUMERICAL]
# 	143 : RunVariance [NUMERICAL]
# 	143 : GrayLevelVariance [NUMERICAL]
# 	136 : RunLengthNonUniformityNormalized [NUMERICAL]
# 	132 : ShortRunEmphasis [NUMERICAL]
# 	115 : RunLengthNonUniformity [NUMERICAL]
# 	109 : RunPercentage [NUMERICAL]
# 	104 : GrayLevelNonUniformityNormalized [NUMERICAL]
# 	97 : LongRunEmphasis [NUMERICAL]
# 	84 : GrayLevelNonUniformity [NUMERICAL]
#
# Attribute in nodes with depth <= 5:
# 	868 : LongRunHighGrayLevelEmphasis [NUMERICAL]
# 	551 : HighGrayLevelRunEmphasis [NUMERICAL]
# 	486 : ShortRunHighGrayLevelEmphasis [NUMERICAL]
# 	439 : ShortRunLowGrayLevelEmphasis [NUMERICAL]
# 	385 : RunEntropy [NUMERICAL]
# 	382 : LowGrayLevelRunEmphasis [NUMERICAL]
# 	315 : GrayLevelVariance [NUMERICAL]
# 	310 : LongRunLowGrayLevelEmphasis [NUMERICAL]
# 	273 : RunLengthNonUniformityNormalized [NUMERICAL]
# 	255 : RunVariance [NUMERICAL]
# 	249 : GrayLevelNonUniformityNormalized [NUMERICAL]
# 	248 : RunLengthNonUniformity [NUMERICAL]
# 	243 : ShortRunEmphasis [NUMERICAL]
# 	230 : GrayLevelNonUniformity [NUMERICAL]
# 	208 : RunPercentage [NUMERICAL]
# 	200 : LongRunEmphasis [NUMERICAL]
#
# Condition type in nodes:
# 	7834 : HigherCondition
# Condition type in nodes with depth <= 0:
# 	300 : HigherCondition
# Condition type in nodes with depth <= 1:
# 	887 : HigherCondition
# Condition type in nodes with depth <= 2:
# 	1865 : HigherCondition
# Condition type in nodes with depth <= 3:
# 	3143 : HigherCondition
# Condition type in nodes with depth <= 5:
# 	5642 : HigherCondition
# Node format: NOT_SET
#
# Training OOB:
# 	trees: 1, Out-of-bag evaluation: accuracy:0.913128 logloss:3.13119
# 	trees: 11, Out-of-bag evaluation: accuracy:0.903623 logloss:3.131
# 	trees: 21, Out-of-bag evaluation: accuracy:0.90002 logloss:1.03867
# 	trees: 31, Out-of-bag evaluation: accuracy:0.894574 logloss:0.596915
# 	trees: 43, Out-of-bag evaluation: accuracy:0.911897 logloss:0.444968
# 	trees: 53, Out-of-bag evaluation: accuracy:0.914427 logloss:0.429391
# 	trees: 63, Out-of-bag evaluation: accuracy:0.914427 logloss:0.429773
# 	trees: 73, Out-of-bag evaluation: accuracy:0.914427 logloss:0.427138
# 	trees: 83, Out-of-bag evaluation: accuracy:0.914427 logloss:0.43029
# 	trees: 93, Out-of-bag evaluation: accuracy:0.914855 logloss:0.428781
# 	trees: 103, Out-of-bag evaluation: accuracy:0.917814 logloss:0.428362
# 	trees: 113, Out-of-bag evaluation: accuracy:0.920772 logloss:0.426349
# 	trees: 123, Out-of-bag evaluation: accuracy:0.917814 logloss:0.42322
# 	trees: 133, Out-of-bag evaluation: accuracy:0.917814 logloss:0.423577
# 	trees: 144, Out-of-bag evaluation: accuracy:0.917814 logloss:0.423602
# 	trees: 154, Out-of-bag evaluation: accuracy:0.917814 logloss:0.422694
# 	trees: 164, Out-of-bag evaluation: accuracy:0.917814 logloss:0.421874
# 	trees: 174, Out-of-bag evaluation: accuracy:0.918242 logloss:0.421477
# 	trees: 184, Out-of-bag evaluation: accuracy:0.917814 logloss:0.422346
# 	trees: 194, Out-of-bag evaluation: accuracy:0.917814 logloss:0.423464
# 	trees: 204, Out-of-bag evaluation: accuracy:0.917814 logloss:0.422735
# 	trees: 214, Out-of-bag evaluation: accuracy:0.917814 logloss:0.422382
# 	trees: 224, Out-of-bag evaluation: accuracy:0.917385 logloss:0.421482
# 	trees: 234, Out-of-bag evaluation: accuracy:0.917814 logloss:0.420771
# 	trees: 244, Out-of-bag evaluation: accuracy:0.917814 logloss:0.421399
# 	trees: 254, Out-of-bag evaluation: accuracy:0.917385 logloss:0.421099
# 	trees: 264, Out-of-bag evaluation: accuracy:0.917814 logloss:0.421275
# 	trees: 274, Out-of-bag evaluation: accuracy:0.917814 logloss:0.421174
# 	trees: 284, Out-of-bag evaluation: accuracy:0.917814 logloss:0.420319
# 	trees: 295, Out-of-bag evaluation: accuracy:0.917385 logloss:0.420434
# 	trees: 300, Out-of-bag evaluation: accuracy:0.917385 logloss:0.419736

# %%
# Model features
model.make_inspector().features()
# Out:
# ["GrayLevelNonUniformity" (1; #0),
#  "GrayLevelNonUniformityNormalized" (1; #1),
#  "GrayLevelVariance" (1; #2),
#  "HighGrayLevelRunEmphasis" (1; #3),
#  "LongRunEmphasis" (1; #4),
#  "LongRunHighGrayLevelEmphasis" (1; #5),
#  "LongRunLowGrayLevelEmphasis" (1; #6),
#  "LowGrayLevelRunEmphasis" (1; #7),
#  "RunEntropy" (1; #8),
#  "RunLengthNonUniformity" (1; #9),
#  "RunLengthNonUniformityNormalized" (1; #10),
#  "RunPercentage" (1; #11),
#  "RunVariance" (1; #12),
#  "ShortRunEmphasis" (1; #13),
#  "ShortRunHighGrayLevelEmphasis" (1; #14),
#  "ShortRunLowGrayLevelEmphasis" (1; #15)]

# %%
# Feature importance
model.make_inspector().variable_importances()
# Out:
# {'INV_MEAN_MIN_DEPTH': [("LongRunHighGrayLevelEmphasis" (1; #5),
#    0.2967486186178288),
#   ("HighGrayLevelRunEmphasis" (1; #3), 0.2388541377808369),
#   ("ShortRunHighGrayLevelEmphasis" (1; #14), 0.20522606770956942),
#   ("ShortRunLowGrayLevelEmphasis" (1; #15), 0.1977411813618121),
#   ("LowGrayLevelRunEmphasis" (1; #7), 0.1824588207492502),
#   ("LongRunLowGrayLevelEmphasis" (1; #6), 0.17055024354499018),
#   ("RunEntropy" (1; #8), 0.16526933132861452),
#   ("RunVariance" (1; #12), 0.1641384140554537),
#   ("RunLengthNonUniformityNormalized" (1; #10), 0.16144237915380652),
#   ("ShortRunEmphasis" (1; #13), 0.15855829804108723),
#   ("GrayLevelVariance" (1; #2), 0.1584827034339728),
#   ("RunLengthNonUniformity" (1; #9), 0.158172388563806),
#   ("LongRunEmphasis" (1; #4), 0.15803935265716557),
#   ("RunPercentage" (1; #11), 0.15749947574213527),
#   ("GrayLevelNonUniformityNormalized" (1; #1), 0.15343701238504123),
#   ("GrayLevelNonUniformity" (1; #0), 0.1528687018351409)],
#  'NUM_AS_ROOT': [("LongRunHighGrayLevelEmphasis" (1; #5), 89.0),
#   ("HighGrayLevelRunEmphasis" (1; #3), 71.0),
#   ("ShortRunHighGrayLevelEmphasis" (1; #14), 48.0),
#   ("ShortRunLowGrayLevelEmphasis" (1; #15), 39.0),
#   ("LowGrayLevelRunEmphasis" (1; #7), 20.0),
#   ("LongRunLowGrayLevelEmphasis" (1; #6), 18.0),
#   ("RunVariance" (1; #12), 8.0),
#   ("LongRunEmphasis" (1; #4), 5.0),
#   ("RunLengthNonUniformity" (1; #9), 1.0),
#   ("RunPercentage" (1; #11), 1.0)],
#  'SUM_SCORE': [("LongRunHighGrayLevelEmphasis" (1; #5), 78809.75143464691),
#   ("HighGrayLevelRunEmphasis" (1; #3), 54991.7390992399),
#   ("ShortRunHighGrayLevelEmphasis" (1; #14), 36618.225475009865),
#   ("ShortRunLowGrayLevelEmphasis" (1; #15), 26848.06771507704),
#   ("LowGrayLevelRunEmphasis" (1; #7), 16264.615650909234),
#   ("LongRunLowGrayLevelEmphasis" (1; #6), 10683.256651013353),
#   ("RunEntropy" (1; #8), 6166.401366885815),
#   ("RunVariance" (1; #12), 4539.876924666924),
#   ("GrayLevelVariance" (1; #2), 4523.290355774122),
#   ("RunLengthNonUniformityNormalized" (1; #10), 4295.19280586248),
#   ("ShortRunEmphasis" (1; #13), 3923.3707803993957),
#   ("RunLengthNonUniformity" (1; #9), 3620.5396501190394),
#   ("LongRunEmphasis" (1; #4), 3465.3576539037904),
#   ("RunPercentage" (1; #11), 3145.2899406295373),
#   ("GrayLevelNonUniformityNormalized" (1; #1), 3141.598879034866),
#   ("GrayLevelNonUniformity" (1; #0), 2888.4990630702173)],
#  'NUM_NODES': [("LongRunHighGrayLevelEmphasis" (1; #5), 1062.0),
#   ("HighGrayLevelRunEmphasis" (1; #3), 708.0),
#   ("ShortRunHighGrayLevelEmphasis" (1; #14), 654.0),
#   ("ShortRunLowGrayLevelEmphasis" (1; #15), 619.0),
#   ("RunEntropy" (1; #8), 559.0),
#   ("LowGrayLevelRunEmphasis" (1; #7), 540.0),
#   ("GrayLevelVariance" (1; #2), 476.0),
#   ("LongRunLowGrayLevelEmphasis" (1; #6), 459.0),
#   ("RunLengthNonUniformityNormalized" (1; #10), 389.0),
#   ("GrayLevelNonUniformityNormalized" (1; #1), 385.0),
#   ("ShortRunEmphasis" (1; #13), 358.0),
#   ("RunVariance" (1; #12), 345.0),
#   ("GrayLevelNonUniformity" (1; #0), 338.0),
#   ("RunLengthNonUniformity" (1; #9), 335.0),
#   ("RunPercentage" (1; #11), 306.0),
#   ("LongRunEmphasis" (1; #4), 301.0)]}

# %%
# Model self evaluation
model.make_inspector().evaluation()
# Out:
# Evaluation(num_examples=1336, accuracy=0.917385397164294, loss=0.4197364398622618, rmse=None, ndcg=None, aucs=None, auuc=None, qini=None)

# %%
logs = model.make_inspector().training_logs()

plt.figure(figsize=(12, 4))
plt.subplot(1, 2, 1)
plt.plot([log.num_trees for log in logs], [log.evaluation.accuracy for log in logs])
plt.xlabel("Number of trees")
plt.ylabel("Accuracy (out-of-bag)")
plt.subplot(1, 2, 2)
plt.plot([log.num_trees for log in logs], [log.evaluation.loss for log in logs])
plt.xlabel("Number of trees")
plt.ylabel("Logloss (out-of-bag)")
plt.show()

# %% [markdown]
# Calculate the score of our hold-out validation dataset

# %%
predictions = model.predict(val_ds)
y_true      = validation_data["label"]

from sklearn.metrics import roc_auc_score
ROC_AUC = roc_auc_score(y_true, predictions)
print("The ROC AUC score is %.5f" % ROC_AUC )
# Out:
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 60ms/step
# The ROC AUC score is 0.99060

# %%
# Compute binary classification metrics with sklearn
import numpy as np
from sklearn.metrics import (
    accuracy_score,
    precision_score,
    recall_score,
    f1_score,
    roc_auc_score,
    average_precision_score,
    confusion_matrix,
    classification_report,
    matthews_corrcoef,
    log_loss,
    brier_score_loss,
)

# Get predictions (probabilities or class labels)
preds = model.predict(test_ds)
# If model outputs probabilities, convert to labels by threshold 0.5
if preds.ndim == 2:
    # For TFDF classification, preds may be class probabilities with shape (N, 2)
    if preds.shape[1] == 2:
        pos_probs = preds[:, 1]
    else:
        # If single-probability column (positive class)
        pos_probs = preds[:, -1]
    y_pred = (pos_probs >= 0.5).astype(int)
else:
    # Already class labels
    y_pred = preds.astype(int)
    pos_probs = None

# Ground truth labels (must be 0/1 integers)
y_true = test_data["label"].astype(int).to_numpy()

# Core metrics
metrics = {}
metrics["accuracy"] = accuracy_score(y_true, y_pred)
metrics["precision"] = precision_score(y_true, y_pred, zero_division=0)
metrics["recall"] = recall_score(y_true, y_pred, zero_division=0)
metrics["f1"] = f1_score(y_true, y_pred, zero_division=0)
metrics["mcc"] = matthews_corrcoef(y_true, y_pred)

# Probabilistic metrics (only if we have probabilities)
if pos_probs is not None:
    metrics["roc_auc"] = roc_auc_score(y_true, pos_probs)
    metrics["pr_auc"] = average_precision_score(y_true, pos_probs)
    metrics["log_loss"] = log_loss(y_true, pos_probs, labels=[0,1])
    metrics["brier_score"] = brier_score_loss(y_true, pos_probs)

# Confusion matrix and detailed report
cm = confusion_matrix(y_true, y_pred, labels=[0,1])
report = classification_report(y_true, y_pred, digits=4)

print("Sklearn binary metrics:")
for k, v in metrics.items():
    print(f"{k}: {v:.4f}")
print("\nConfusion matrix:\n", cm)
print("\nClassification report:\n", report)
# Out:
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 65ms/step
# Sklearn binary metrics:
# accuracy: 0.9503
# precision: 0.8154
# recall: 0.8833
# f1: 0.8480
# mcc: 0.8193
# roc_auc: 0.9714
# pr_auc: 0.9265
# log_loss: 0.1616
# brier_score: 0.0394
#
# Confusion matrix:
#  [[310  12]
#  [  7  53]]
#
# Classification report:
#                precision    recall  f1-score   support
#
#            0     0.9779    0.9627    0.9703       322
#            1     0.8154    0.8833    0.8480        60
#
#     accuracy                         0.9503       382
#    macro avg     0.8967    0.9230    0.9091       382
# weighted avg     0.9524    0.9503    0.9511       382
