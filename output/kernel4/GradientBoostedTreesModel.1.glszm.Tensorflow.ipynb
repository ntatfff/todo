# %%
# Import packages and modules
import numpy  as np
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow_decision_forests as tfdf

from sklearn.model_selection import train_test_split
# Out:
# 2026-08-15 05:00:28.952087: I tensorflow/core/util/port.cc:113] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2026-08-15 05:00:29.307957: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2026-08-15 05:00:34.119195: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
# Check the version of TensorFlow Decision Forests
print("Found TensorFlow Decision Forests v" + tfdf.__version__)
# Out:
# Found TensorFlow Decision Forests v1.9.1

# %%
datasetPath = 'dataset/firstorder/kernel5/dataset.csv'

# %%
# Parameters
datasetPath = "dataset/glszm/kernel4/1.dataset.csv"

# %%
# train/validation/test = 70/10/20
dataset = pd.read_csv(datasetPath)

train_data, temp_data = train_test_split(dataset, test_size=0.3, random_state=42)
validation_data, test_data = train_test_split(temp_data, test_size=2/3, random_state=42)

# %%
from sklearn.utils.class_weight import compute_class_weight

# tinh class weight tren tap train
classes = np.array([0, 1])
weights = compute_class_weight(class_weight="balanced", classes=classes, y=train_data["label"])
class_weight = {0: weights[0], 1: weights[1]}

# gan sample_weight cho tung dong
train_data["sample_weight"] = train_data["label"].map(class_weight)
validation_data["sample_weight"] = validation_data["label"].map(class_weight)
test_data["sample_weight"] = test_data["label"].map(class_weight)

# Convert the dataset into a TensorFlow dataset.
train_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    train_data, label="label", weight="sample_weight"
)         
val_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    validation_data, label="label", weight="sample_weight"
)
test_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    test_data, label="label", weight="sample_weight"
)
# Out:
# 2026-08-15 05:00:47.745493: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:984] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2026-08-15 05:00:47.747514: W tensorflow/core/common_runtime/gpu/gpu_device.cc:2251] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...

# %%
import keras

# %%
# %%time

# Train a Gradient Boosted Trees model.
model = tfdf.keras.GradientBoostedTreesModel()

# Add evaluation metrics
model.compile(
    metrics=["accuracy"]
)
model.fit(x=train_ds)

# # Train a Gradient Boosted Trees model.
# model = tfdf.keras.GradientBoostedTreesModel(num_trees=1500)
# model.fit(train_ds)
# Out:
# Use /tmp/tmpt556ijjj as temporary training directory
# Reading training dataset...
# [WARNING 26-08-15 05:00:47.9018 UTC gradient_boosted_trees.cc:1840] "goss_alpha" set but "sampling_method" not equal to "GOSS".
# [WARNING 26-08-15 05:00:47.9020 UTC gradient_boosted_trees.cc:1851] "goss_beta" set but "sampling_method" not equal to "GOSS".
# [WARNING 26-08-15 05:00:47.9020 UTC gradient_boosted_trees.cc:1865] "selective_gradient_boosting_ratio" set but "sampling_method" not equal to "SELGB".
# Training dataset read in 0:00:02.666295. Found 1554 examples.
# Training model...
# Model trained in 0:00:00.357383
# Compiling model...
# [INFO 26-08-15 05:00:50.9540 UTC kernel.cc:1233] Loading model from path /tmp/tmpt556ijjj/model/ with prefix e2aabad5f70143ab
# [INFO 26-08-15 05:00:50.9567 UTC quick_scorer_extended.cc:911] The binary was compiled without AVX2 support, but your CPU supports it. Enable it for faster model inference.
# [INFO 26-08-15 05:00:50.9568 UTC abstract_model.cc:1362] Engine "GradientBoostedTreesQuickScorerExtended" built
# [INFO 26-08-15 05:00:50.9568 UTC kernel.cc:1061] Use fast generic engine
# Model compiled.
# CPU times: user 6.2 s, sys: 418 ms, total: 6.62 s
# Wall time: 6.33 s

# %%
# Evaluate the model
evaluate = model.evaluate(val_ds, return_dict=True)
print()

for name, value in evaluate.items():
    print(f"{name}: {value:.4f}")
# Out:
# WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 1/1 [==============================] - ETA: 0s - loss: 0.0000e+00 - accuracy: 0.9820
# 1/1 [==============================] - 3s 3s/step - loss: 0.0000e+00 - accuracy: 0.9820
# loss: 0.0000
# accuracy: 0.9820

# %%
# Model Summary
model.summary()
# Out:
# Model: "gradient_boosted_trees_model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
# =================================================================
# Total params: 1 (1.00 Byte)
# Trainable params: 0 (0.00 Byte)
# Non-trainable params: 1 (1.00 Byte)
# _________________________________________________________________
# Type: "GRADIENT_BOOSTED_TREES"
# Task: CLASSIFICATION
# Label: "__LABEL"
#
# Input Features (16):
# 	GrayLevelNonUniformity
# 	GrayLevelNonUniformityNormalized
# 	GrayLevelVariance
# 	HighGrayLevelZoneEmphasis
# 	LargeAreaEmphasis
# 	LargeAreaHighGrayLevelEmphasis
# 	LargeAreaLowGrayLevelEmphasis
# 	LowGrayLevelZoneEmphasis
# 	SizeZoneNonUniformity
# 	SizeZoneNonUniformityNormalized
# 	SmallAreaEmphasis
# 	SmallAreaHighGrayLevelEmphasis
# 	SmallAreaLowGrayLevelEmphasis
# 	ZoneEntropy
# 	ZonePercentage
# 	ZoneVariance
#
# Trained with weights
#
# Variable Importance: INV_MEAN_MIN_DEPTH:
#     1.        "HighGrayLevelZoneEmphasis"  0.479566 ################
#     2.   "SmallAreaHighGrayLevelEmphasis"  0.275073 ####
#     3.    "LargeAreaLowGrayLevelEmphasis"  0.258090 ###
#     4.           "GrayLevelNonUniformity"  0.249153 ###
#     5.                      "ZoneEntropy"  0.235318 ##
#     6. "GrayLevelNonUniformityNormalized"  0.212186 #
#     7.                     "ZoneVariance"  0.205286
#     8.                "LargeAreaEmphasis"  0.200172
#     9.         "LowGrayLevelZoneEmphasis"  0.197919
#    10.    "SmallAreaLowGrayLevelEmphasis"  0.195781
#    11.   "LargeAreaHighGrayLevelEmphasis"  0.195720
#    12.                "SmallAreaEmphasis"  0.194967
#    13.                   "ZonePercentage"  0.193853
#    14.                "GrayLevelVariance"  0.193031
#    15.            "SizeZoneNonUniformity"  0.192776
#    16.  "SizeZoneNonUniformityNormalized"  0.192711
#
# Variable Importance: NUM_AS_ROOT:
#     1.      "HighGrayLevelZoneEmphasis" 40.000000 ################
#     2. "SmallAreaHighGrayLevelEmphasis" 18.000000
#
# Variable Importance: NUM_NODES:
#     1.        "HighGrayLevelZoneEmphasis" 159.000000 ################
#     2.    "LargeAreaLowGrayLevelEmphasis" 121.000000 ###########
#     3.           "GrayLevelNonUniformity" 120.000000 ###########
#     4.                      "ZoneEntropy" 94.000000 #########
#     5.   "SmallAreaHighGrayLevelEmphasis" 87.000000 ########
#     6. "GrayLevelNonUniformityNormalized" 49.000000 ####
#     7.                     "ZoneVariance" 35.000000 ##
#     8.         "LowGrayLevelZoneEmphasis" 25.000000 #
#     9.   "LargeAreaHighGrayLevelEmphasis" 23.000000 #
#    10.                "LargeAreaEmphasis" 22.000000 #
#    11.    "SmallAreaLowGrayLevelEmphasis" 15.000000
#    12.                "SmallAreaEmphasis" 12.000000
#    13.                "GrayLevelVariance" 11.000000
#    14.                   "ZonePercentage" 11.000000
#    15.  "SizeZoneNonUniformityNormalized"  9.000000
#    16.            "SizeZoneNonUniformity"  8.000000
#
# Variable Importance: SUM_SCORE:
#     1.        "HighGrayLevelZoneEmphasis" 1701.120638 ################
#     2.                      "ZoneEntropy" 120.355299 #
#     3.           "GrayLevelNonUniformity" 37.078337
#     4.    "LargeAreaLowGrayLevelEmphasis" 23.283011
#     5.   "SmallAreaHighGrayLevelEmphasis" 15.845683
#     6.                     "ZoneVariance" 10.368528
#     7. "GrayLevelNonUniformityNormalized"  1.601024
#     8.                "LargeAreaEmphasis"  0.937430
#     9.         "LowGrayLevelZoneEmphasis"  0.528352
#    10.                   "ZonePercentage"  0.518902
#    11.            "SizeZoneNonUniformity"  0.218000
#    12.    "SmallAreaLowGrayLevelEmphasis"  0.214459
#    13.                "GrayLevelVariance"  0.151849
#    14.   "LargeAreaHighGrayLevelEmphasis"  0.110876
#    15.                "SmallAreaEmphasis"  0.099932
#    16.  "SizeZoneNonUniformityNormalized"  0.040413
#
#
#
# Loss: BINOMIAL_LOG_LIKELIHOOD
# Validation loss value: 0.0885524
# Number of trees per iteration: 1
# Node format: NOT_SET
# Number of trees: 58
# Total number of nodes: 1660
#
# Number of nodes by tree:
# Count: 58 Average: 28.6207 StdDev: 7.81208
# Min: 17 Max: 43 Ignored: 0
# ----------------------------------------------
# [ 17, 18) 4   6.90%   6.90% ####
# [ 18, 19) 0   0.00%   6.90%
# [ 19, 21) 8  13.79%  20.69% #########
# [ 21, 22) 7  12.07%  32.76% ########
# [ 22, 23) 0   0.00%  32.76%
# [ 23, 25) 1   1.72%  34.48% #
# [ 25, 26) 3   5.17%  39.66% ###
# [ 26, 27) 0   0.00%  39.66%
# [ 27, 29) 5   8.62%  48.28% ######
# [ 29, 30) 3   5.17%  53.45% ###
# [ 30, 31) 0   0.00%  53.45%
# [ 31, 33) 4   6.90%  60.34% ####
# [ 33, 34) 2   3.45%  63.79% ##
# [ 34, 35) 0   0.00%  63.79%
# [ 35, 37) 9  15.52%  79.31% ##########
# [ 37, 38) 5   8.62%  87.93% ######
# [ 38, 39) 0   0.00%  87.93%
# [ 39, 41) 3   5.17%  93.10% ###
# [ 41, 42) 3   5.17%  98.28% ###
# [ 42, 43] 1   1.72% 100.00% #
#
# Depth by leafs:
# Count: 859 Average: 4.29336 StdDev: 0.983018
# Min: 2 Max: 5 Ignored: 0
# ----------------------------------------------
# [ 2, 3)  64   7.45%   7.45% #
# [ 3, 4) 134  15.60%  23.05% ###
# [ 4, 5) 147  17.11%  40.16% ###
# [ 5, 5] 514  59.84% 100.00% ##########
#
# Number of training obs by leaf:
# Count: 859 Average: 96.2165 StdDev: 296.836
# Min: 5 Max: 1276 Ignored: 0
# ----------------------------------------------
# [    5,   68) 762  88.71%  88.71% ##########
# [   68,  132)  26   3.03%  91.73%
# [  132,  195)   5   0.58%  92.32%
# [  195,  259)   5   0.58%  92.90%
# [  259,  323)   2   0.23%  93.13%
# [  323,  386)   0   0.00%  93.13%
# [  386,  450)   1   0.12%  93.25%
# [  450,  513)   0   0.00%  93.25%
# [  513,  577)   0   0.00%  93.25%
# [  577,  641)   0   0.00%  93.25%
# [  641,  704)   0   0.00%  93.25%
# [  704,  768)   0   0.00%  93.25%
# [  768,  831)   0   0.00%  93.25%
# [  831,  895)   1   0.12%  93.36%
# [  895,  959)   2   0.23%  93.60%
# [  959, 1022)   3   0.35%  93.95%
# [ 1022, 1086)   3   0.35%  94.30%
# [ 1086, 1149)   4   0.47%  94.76%
# [ 1149, 1213)  12   1.40%  96.16%
# [ 1213, 1276]  33   3.84% 100.00%
#
# Attribute in nodes:
# 	159 : HighGrayLevelZoneEmphasis [NUMERICAL]
# 	121 : LargeAreaLowGrayLevelEmphasis [NUMERICAL]
# 	120 : GrayLevelNonUniformity [NUMERICAL]
# 	94 : ZoneEntropy [NUMERICAL]
# 	87 : SmallAreaHighGrayLevelEmphasis [NUMERICAL]
# 	49 : GrayLevelNonUniformityNormalized [NUMERICAL]
# 	35 : ZoneVariance [NUMERICAL]
# 	25 : LowGrayLevelZoneEmphasis [NUMERICAL]
# 	23 : LargeAreaHighGrayLevelEmphasis [NUMERICAL]
# 	22 : LargeAreaEmphasis [NUMERICAL]
# 	15 : SmallAreaLowGrayLevelEmphasis [NUMERICAL]
# 	12 : SmallAreaEmphasis [NUMERICAL]
# 	11 : ZonePercentage [NUMERICAL]
# 	11 : GrayLevelVariance [NUMERICAL]
# 	9 : SizeZoneNonUniformityNormalized [NUMERICAL]
# 	8 : SizeZoneNonUniformity [NUMERICAL]
#
# Attribute in nodes with depth <= 0:
# 	40 : HighGrayLevelZoneEmphasis [NUMERICAL]
# 	18 : SmallAreaHighGrayLevelEmphasis [NUMERICAL]
#
# Attribute in nodes with depth <= 1:
# 	55 : HighGrayLevelZoneEmphasis [NUMERICAL]
# 	25 : ZoneEntropy [NUMERICAL]
# 	25 : SmallAreaHighGrayLevelEmphasis [NUMERICAL]
# 	20 : LargeAreaLowGrayLevelEmphasis [NUMERICAL]
# 	19 : GrayLevelNonUniformity [NUMERICAL]
# 	16 : GrayLevelNonUniformityNormalized [NUMERICAL]
# 	6 : LargeAreaEmphasis [NUMERICAL]
# 	5 : ZoneVariance [NUMERICAL]
# 	3 : LowGrayLevelZoneEmphasis [NUMERICAL]
#
# Attribute in nodes with depth <= 2:
# 	74 : HighGrayLevelZoneEmphasis [NUMERICAL]
# 	59 : ZoneEntropy [NUMERICAL]
# 	56 : LargeAreaLowGrayLevelEmphasis [NUMERICAL]
# 	46 : GrayLevelNonUniformity [NUMERICAL]
# 	32 : SmallAreaHighGrayLevelEmphasis [NUMERICAL]
# 	20 : GrayLevelNonUniformityNormalized [NUMERICAL]
# 	14 : ZoneVariance [NUMERICAL]
# 	9 : LargeAreaEmphasis [NUMERICAL]
# 	6 : SmallAreaLowGrayLevelEmphasis [NUMERICAL]
# 	6 : SmallAreaEmphasis [NUMERICAL]
# 	6 : LargeAreaHighGrayLevelEmphasis [NUMERICAL]
# 	4 : ZonePercentage [NUMERICAL]
# 	4 : SizeZoneNonUniformityNormalized [NUMERICAL]
# 	4 : LowGrayLevelZoneEmphasis [NUMERICAL]
# 	2 : GrayLevelVariance [NUMERICAL]
#
# Attribute in nodes with depth <= 3:
# 	124 : HighGrayLevelZoneEmphasis [NUMERICAL]
# 	78 : GrayLevelNonUniformity [NUMERICAL]
# 	76 : ZoneEntropy [NUMERICAL]
# 	73 : LargeAreaLowGrayLevelEmphasis [NUMERICAL]
# 	59 : SmallAreaHighGrayLevelEmphasis [NUMERICAL]
# 	34 : GrayLevelNonUniformityNormalized [NUMERICAL]
# 	19 : ZoneVariance [NUMERICAL]
# 	15 : LargeAreaHighGrayLevelEmphasis [NUMERICAL]
# 	11 : SmallAreaLowGrayLevelEmphasis [NUMERICAL]
# 	11 : SmallAreaEmphasis [NUMERICAL]
# 	11 : LargeAreaEmphasis [NUMERICAL]
# 	10 : LowGrayLevelZoneEmphasis [NUMERICAL]
# 	7 : ZonePercentage [NUMERICAL]
# 	7 : SizeZoneNonUniformity [NUMERICAL]
# 	6 : SizeZoneNonUniformityNormalized [NUMERICAL]
# 	3 : GrayLevelVariance [NUMERICAL]
#
# Attribute in nodes with depth <= 5:
# 	159 : HighGrayLevelZoneEmphasis [NUMERICAL]
# 	121 : LargeAreaLowGrayLevelEmphasis [NUMERICAL]
# 	120 : GrayLevelNonUniformity [NUMERICAL]
# 	94 : ZoneEntropy [NUMERICAL]
# 	87 : SmallAreaHighGrayLevelEmphasis [NUMERICAL]
# 	49 : GrayLevelNonUniformityNormalized [NUMERICAL]
# 	35 : ZoneVariance [NUMERICAL]
# 	25 : LowGrayLevelZoneEmphasis [NUMERICAL]
# 	23 : LargeAreaHighGrayLevelEmphasis [NUMERICAL]
# 	22 : LargeAreaEmphasis [NUMERICAL]
# 	15 : SmallAreaLowGrayLevelEmphasis [NUMERICAL]
# 	12 : SmallAreaEmphasis [NUMERICAL]
# 	11 : ZonePercentage [NUMERICAL]
# 	11 : GrayLevelVariance [NUMERICAL]
# 	9 : SizeZoneNonUniformityNormalized [NUMERICAL]
# 	8 : SizeZoneNonUniformity [NUMERICAL]
#
# Condition type in nodes:
# 	801 : HigherCondition
# Condition type in nodes with depth <= 0:
# 	58 : HigherCondition
# Condition type in nodes with depth <= 1:
# 	174 : HigherCondition
# Condition type in nodes with depth <= 2:
# 	342 : HigherCondition
# Condition type in nodes with depth <= 3:
# 	544 : HigherCondition
# Condition type in nodes with depth <= 5:
# 	801 : HigherCondition
#
# Training logs:
# Number of iteration to final model: 58
# 	Iter:1 train-loss:1.198730 valid-loss:1.201008  train-accuracy:0.996629 valid-accuracy:0.991529
# 	Iter:2 train-loss:1.045045 valid-loss:1.050665  train-accuracy:0.997378 valid-accuracy:0.991529
# 	Iter:3 train-loss:0.916936 valid-loss:0.925642  train-accuracy:0.996629 valid-accuracy:0.987293
# 	Iter:4 train-loss:0.808636 valid-loss:0.818475  train-accuracy:0.997378 valid-accuracy:0.991529
# 	Iter:5 train-loss:0.716134 valid-loss:0.728225  train-accuracy:0.996629 valid-accuracy:0.991529
# 	Iter:6 train-loss:0.636528 valid-loss:0.650680  train-accuracy:0.997378 valid-accuracy:0.991529
# 	Iter:16 train-loss:0.222197 valid-loss:0.253058  train-accuracy:0.997378 valid-accuracy:0.991529
# 	Iter:26 train-loss:0.088590 valid-loss:0.135794  train-accuracy:0.997753 valid-accuracy:0.991529
# 	Iter:36 train-loss:0.035487 valid-loss:0.100464  train-accuracy:0.998876 valid-accuracy:0.991529
# 	Iter:46 train-loss:0.013070 valid-loss:0.097189  train-accuracy:1.000000 valid-accuracy:0.991529
# 	Iter:56 train-loss:0.005239 valid-loss:0.089972  train-accuracy:1.000000 valid-accuracy:0.991529
# 	Iter:66 train-loss:0.002267 valid-loss:0.090384  train-accuracy:1.000000 valid-accuracy:0.991529
# 	Iter:76 train-loss:0.001039 valid-loss:0.103601  train-accuracy:1.000000 valid-accuracy:0.991529
# 	Iter:86 train-loss:0.000460 valid-loss:0.112907  train-accuracy:1.000000 valid-accuracy:0.991529

# %%
# Model features
model.make_inspector().features()
# Out:
# ["GrayLevelNonUniformity" (1; #0),
#  "GrayLevelNonUniformityNormalized" (1; #1),
#  "GrayLevelVariance" (1; #2),
#  "HighGrayLevelZoneEmphasis" (1; #3),
#  "LargeAreaEmphasis" (1; #4),
#  "LargeAreaHighGrayLevelEmphasis" (1; #5),
#  "LargeAreaLowGrayLevelEmphasis" (1; #6),
#  "LowGrayLevelZoneEmphasis" (1; #7),
#  "SizeZoneNonUniformity" (1; #8),
#  "SizeZoneNonUniformityNormalized" (1; #9),
#  "SmallAreaEmphasis" (1; #10),
#  "SmallAreaHighGrayLevelEmphasis" (1; #11),
#  "SmallAreaLowGrayLevelEmphasis" (1; #12),
#  "ZoneEntropy" (1; #13),
#  "ZonePercentage" (1; #14),
#  "ZoneVariance" (1; #15)]

# %%
# Feature importance
model.make_inspector().variable_importances()
# Out:
# {'INV_MEAN_MIN_DEPTH': [("HighGrayLevelZoneEmphasis" (1; #3),
#    0.4795656633589787),
#   ("SmallAreaHighGrayLevelEmphasis" (1; #11), 0.2750728659057682),
#   ("LargeAreaLowGrayLevelEmphasis" (1; #6), 0.2580895724611086),
#   ("GrayLevelNonUniformity" (1; #0), 0.2491531615063809),
#   ("ZoneEntropy" (1; #13), 0.23531788155459232),
#   ("GrayLevelNonUniformityNormalized" (1; #1), 0.2121863733453628),
#   ("ZoneVariance" (1; #15), 0.20528561238012505),
#   ("LargeAreaEmphasis" (1; #4), 0.20017164252278885),
#   ("LowGrayLevelZoneEmphasis" (1; #7), 0.1979185269138695),
#   ("SmallAreaLowGrayLevelEmphasis" (1; #12), 0.19578142265099455),
#   ("LargeAreaHighGrayLevelEmphasis" (1; #5), 0.1957202236502878),
#   ("SmallAreaEmphasis" (1; #10), 0.194966708436421),
#   ("ZonePercentage" (1; #14), 0.1938527797454368),
#   ("GrayLevelVariance" (1; #2), 0.19303115352090694),
#   ("SizeZoneNonUniformity" (1; #8), 0.19277605700262299),
#   ("SizeZoneNonUniformityNormalized" (1; #9), 0.19271089364436886)],
#  'NUM_AS_ROOT': [("HighGrayLevelZoneEmphasis" (1; #3), 40.0),
#   ("SmallAreaHighGrayLevelEmphasis" (1; #11), 18.0)],
#  'SUM_SCORE': [("HighGrayLevelZoneEmphasis" (1; #3), 1701.1206375813183),
#   ("ZoneEntropy" (1; #13), 120.35529918739758),
#   ("GrayLevelNonUniformity" (1; #0), 37.078337008594026),
#   ("LargeAreaLowGrayLevelEmphasis" (1; #6), 23.283010727015125),
#   ("SmallAreaHighGrayLevelEmphasis" (1; #11), 15.84568328823823),
#   ("ZoneVariance" (1; #15), 10.368528075484473),
#   ("GrayLevelNonUniformityNormalized" (1; #1), 1.6010236877459572),
#   ("LargeAreaEmphasis" (1; #4), 0.9374297306492212),
#   ("LowGrayLevelZoneEmphasis" (1; #7), 0.5283523399545158),
#   ("ZonePercentage" (1; #14), 0.5189017826959638),
#   ("SizeZoneNonUniformity" (1; #8), 0.21800000266215078),
#   ("SmallAreaLowGrayLevelEmphasis" (1; #12), 0.21445884655602893),
#   ("GrayLevelVariance" (1; #2), 0.1518492034339642),
#   ("LargeAreaHighGrayLevelEmphasis" (1; #5), 0.11087567885189084),
#   ("SmallAreaEmphasis" (1; #10), 0.09993165896048722),
#   ("SizeZoneNonUniformityNormalized" (1; #9), 0.04041270221312846)],
#  'NUM_NODES': [("HighGrayLevelZoneEmphasis" (1; #3), 159.0),
#   ("LargeAreaLowGrayLevelEmphasis" (1; #6), 121.0),
#   ("GrayLevelNonUniformity" (1; #0), 120.0),
#   ("ZoneEntropy" (1; #13), 94.0),
#   ("SmallAreaHighGrayLevelEmphasis" (1; #11), 87.0),
#   ("GrayLevelNonUniformityNormalized" (1; #1), 49.0),
#   ("ZoneVariance" (1; #15), 35.0),
#   ("LowGrayLevelZoneEmphasis" (1; #7), 25.0),
#   ("LargeAreaHighGrayLevelEmphasis" (1; #5), 23.0),
#   ("LargeAreaEmphasis" (1; #4), 22.0),
#   ("SmallAreaLowGrayLevelEmphasis" (1; #12), 15.0),
#   ("SmallAreaEmphasis" (1; #10), 12.0),
#   ("GrayLevelVariance" (1; #2), 11.0),
#   ("ZonePercentage" (1; #14), 11.0),
#   ("SizeZoneNonUniformityNormalized" (1; #9), 9.0),
#   ("SizeZoneNonUniformity" (1; #8), 8.0)]}

# %%
# Model self evaluation
model.make_inspector().evaluation()
# Out:
# Evaluation(num_examples=None, accuracy=0.9915286302566528, loss=0.08855237066745758, rmse=None, ndcg=None, aucs=None, auuc=None, qini=None)

# %%
logs = model.make_inspector().training_logs()

plt.figure(figsize=(12, 4))
plt.subplot(1, 2, 1)
plt.plot([log.num_trees for log in logs], [log.evaluation.accuracy for log in logs])
plt.xlabel("Number of trees")
plt.ylabel("Accuracy (out-of-bag)")
plt.subplot(1, 2, 2)
plt.plot([log.num_trees for log in logs], [log.evaluation.loss for log in logs])
plt.xlabel("Number of trees")
plt.ylabel("Logloss (out-of-bag)")
plt.show()

# %% [markdown]
# Calculate the score of our hold-out validation dataset

# %%
predictions = model.predict(val_ds)
y_true      = validation_data["label"]

from sklearn.metrics import roc_auc_score
ROC_AUC = roc_auc_score(y_true, predictions)
print("The ROC AUC score is %.5f" % ROC_AUC )
# Out:
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 60ms/step
# The ROC AUC score is 0.93989

# %%
# Compute binary classification metrics with sklearn
import numpy as np
from sklearn.metrics import (
    accuracy_score,
    precision_score,
    recall_score,
    f1_score,
    roc_auc_score,
    average_precision_score,
    confusion_matrix,
    classification_report,
    matthews_corrcoef,
    log_loss,
    brier_score_loss,
)

# Get predictions (probabilities or class labels)
preds = model.predict(test_ds)
# If model outputs probabilities, convert to labels by threshold 0.5
if preds.ndim == 2:
    # For TFDF classification, preds may be class probabilities with shape (N, 2)
    if preds.shape[1] == 2:
        pos_probs = preds[:, 1]
    else:
        # If single-probability column (positive class)
        pos_probs = preds[:, -1]
    y_pred = (pos_probs >= 0.5).astype(int)
else:
    # Already class labels
    y_pred = preds.astype(int)
    pos_probs = None

# Ground truth labels (must be 0/1 integers)
y_true = test_data["label"].astype(int).to_numpy()

# Core metrics
metrics = {}
metrics["accuracy"] = accuracy_score(y_true, y_pred)
metrics["precision"] = precision_score(y_true, y_pred, zero_division=0)
metrics["recall"] = recall_score(y_true, y_pred, zero_division=0)
metrics["f1"] = f1_score(y_true, y_pred, zero_division=0)
metrics["mcc"] = matthews_corrcoef(y_true, y_pred)

# Probabilistic metrics (only if we have probabilities)
if pos_probs is not None:
    metrics["roc_auc"] = roc_auc_score(y_true, pos_probs)
    metrics["pr_auc"] = average_precision_score(y_true, pos_probs)
    metrics["log_loss"] = log_loss(y_true, pos_probs, labels=[0,1])
    metrics["brier_score"] = brier_score_loss(y_true, pos_probs)

# Confusion matrix and detailed report
cm = confusion_matrix(y_true, y_pred, labels=[0,1])
report = classification_report(y_true, y_pred, digits=4)

print("Sklearn binary metrics:")
for k, v in metrics.items():
    print(f"{k}: {v:.4f}")
print("\nConfusion matrix:\n", cm)
print("\nClassification report:\n", report)
# Out:
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 63ms/step
# Sklearn binary metrics:
# accuracy: 0.9842
# precision: 0.7917
# recall: 0.9048
# f1: 0.8444
# mcc: 0.8382
# roc_auc: 0.9950
# pr_auc: 0.9375
# log_loss: 0.0530
# brier_score: 0.0123
#
# Confusion matrix:
#  [[418   5]
#  [  2  19]]
#
# Classification report:
#                precision    recall  f1-score   support
#
#            0     0.9952    0.9882    0.9917       423
#            1     0.7917    0.9048    0.8444        21
#
#     accuracy                         0.9842       444
#    macro avg     0.8935    0.9465    0.9181       444
# weighted avg     0.9856    0.9842    0.9847       444
