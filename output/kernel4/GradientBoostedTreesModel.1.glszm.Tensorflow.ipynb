# %%
# Import packages and modules
import numpy  as np
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow_decision_forests as tfdf

from sklearn.model_selection import train_test_split
# Out:
# 2026-08-10 17:12:49.809154: I tensorflow/core/util/port.cc:113] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2026-08-10 17:12:50.224254: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2026-08-10 17:12:54.999203: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
# Check the version of TensorFlow Decision Forests
print("Found TensorFlow Decision Forests v" + tfdf.__version__)
# Out:
# Found TensorFlow Decision Forests v1.9.1

# %%
datasetPath = 'dataset/firstorder/kernel5-radius5/dataset.csv'

# %%
# Parameters
datasetPath = "dataset/glszm/kernel4-radius4/dataset.1p.csv"

# %%
# train/validation/test = 70/10/20
dataset = pd.read_csv(datasetPath)

train_data, temp_data = train_test_split(dataset, test_size=0.3, random_state=42)
validation_data, test_data = train_test_split(temp_data, test_size=2/3, random_state=42)

# %%
from sklearn.utils.class_weight import compute_class_weight

# tinh class weight tren tap train
classes = np.array([0, 1])
weights = compute_class_weight(class_weight="balanced", classes=classes, y=train_data["label"])
class_weight = {0: weights[0], 1: weights[1]}

# gan sample_weight cho tung dong
train_data["sample_weight"] = train_data["label"].map(class_weight)
validation_data["sample_weight"] = validation_data["label"].map(class_weight)
test_data["sample_weight"] = test_data["label"].map(class_weight)

# Convert the dataset into a TensorFlow dataset.
train_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    train_data, label="label", weight="sample_weight"
)         
val_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    validation_data, label="label", weight="sample_weight"
)
test_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    test_data, label="label", weight="sample_weight"
)
# Out:
# 2026-08-10 17:13:07.853009: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:984] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2026-08-10 17:13:07.854199: W tensorflow/core/common_runtime/gpu/gpu_device.cc:2251] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...

# %%
import keras

# %%
# %%time

# Train a Gradient Boosted Trees model.
model = tfdf.keras.GradientBoostedTreesModel()

# Add evaluation metrics
model.compile(
    metrics=["accuracy"]
)
model.fit(x=train_ds)

# # Train a Gradient Boosted Trees model.
# model = tfdf.keras.GradientBoostedTreesModel(num_trees=1500)
# model.fit(train_ds)
# Out:
# Use /tmp/tmp8hoklhmh as temporary training directory
# Reading training dataset...
# [WARNING 26-08-10 17:13:08.0233 UTC gradient_boosted_trees.cc:1840] "goss_alpha" set but "sampling_method" not equal to "GOSS".
# [WARNING 26-08-10 17:13:08.0235 UTC gradient_boosted_trees.cc:1851] "goss_beta" set but "sampling_method" not equal to "GOSS".
# [WARNING 26-08-10 17:13:08.0235 UTC gradient_boosted_trees.cc:1865] "selective_gradient_boosting_ratio" set but "sampling_method" not equal to "SELGB".
# Training dataset read in 0:00:02.560735. Found 1542 examples.
# Training model...
# Model trained in 0:00:01.617509
# Compiling model...
# [INFO 26-08-10 17:13:12.2190 UTC kernel.cc:1233] Loading model from path /tmp/tmp8hoklhmh/model/ with prefix cace7427a248489a
# [INFO 26-08-10 17:13:12.2278 UTC quick_scorer_extended.cc:911] The binary was compiled without AVX2 support, but your CPU supports it. Enable it for faster model inference.
# [INFO 26-08-10 17:13:12.2283 UTC abstract_model.cc:1362] Engine "GradientBoostedTreesQuickScorerExtended" built
# [INFO 26-08-10 17:13:12.2283 UTC kernel.cc:1061] Use fast generic engine
# Model compiled.
# CPU times: user 8.38 s, sys: 2.11 s, total: 10.5 s
# Wall time: 7.24 s

# %%
# Evaluate the model
evaluate = model.evaluate(val_ds, return_dict=True)
print()

for name, value in evaluate.items():
    print(f"{name}: {value:.4f}")
# Out:
# WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 1/1 [==============================] - ETA: 0s - loss: 0.0000e+00 - accuracy: 1.0000
# 1/1 [==============================] - 3s 3s/step - loss: 0.0000e+00 - accuracy: 1.0000
# loss: 0.0000
# accuracy: 1.0000

# %%
# Model Summary
model.summary()
# Out:
# Model: "gradient_boosted_trees_model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
# =================================================================
# Total params: 1 (1.00 Byte)
# Trainable params: 0 (0.00 Byte)
# Non-trainable params: 1 (1.00 Byte)
# _________________________________________________________________
# Type: "GRADIENT_BOOSTED_TREES"
# Task: CLASSIFICATION
# Label: "__LABEL"
#
# Input Features (34):
# 	10Percentile
# 	90Percentile
# 	Energy
# 	Entropy
# 	GrayLevelNonUniformity
# 	GrayLevelNonUniformityNormalized
# 	GrayLevelVariance
# 	HighGrayLevelZoneEmphasis
# 	InterquartileRange
# 	Kurtosis
# 	LargeAreaEmphasis
# 	LargeAreaHighGrayLevelEmphasis
# 	LargeAreaLowGrayLevelEmphasis
# 	LowGrayLevelZoneEmphasis
# 	Maximum
# 	Mean
# 	MeanAbsoluteDeviation
# 	Median
# 	Minimum
# 	Range
# 	RobustMeanAbsoluteDeviation
# 	RootMeanSquared
# 	SizeZoneNonUniformity
# 	SizeZoneNonUniformityNormalized
# 	Skewness
# 	SmallAreaEmphasis
# 	SmallAreaHighGrayLevelEmphasis
# 	SmallAreaLowGrayLevelEmphasis
# 	TotalEnergy
# 	Uniformity
# 	Variance
# 	ZoneEntropy
# 	ZonePercentage
# 	ZoneVariance
#
# Trained with weights
#
# Variable Importance: INV_MEAN_MIN_DEPTH:
#     1.        "HighGrayLevelZoneEmphasis"  0.467272 ################
#     2.    "LargeAreaLowGrayLevelEmphasis"  0.304573 ######
#     3.                   "ZonePercentage"  0.264341 ###
#     4.                "GrayLevelVariance"  0.259559 ###
#     5.   "SmallAreaHighGrayLevelEmphasis"  0.227567 #
#     6.         "LowGrayLevelZoneEmphasis"  0.213946
#     7.   "LargeAreaHighGrayLevelEmphasis"  0.212605
#     8.  "SizeZoneNonUniformityNormalized"  0.209144
#     9.    "SmallAreaLowGrayLevelEmphasis"  0.208678
#    10.                "SmallAreaEmphasis"  0.207055
#    11. "GrayLevelNonUniformityNormalized"  0.204449
#    12.            "SizeZoneNonUniformity"  0.203875
#    13.      "RobustMeanAbsoluteDeviation"  0.203567
#    14.                     "ZoneVariance"  0.203044
#    15.                      "ZoneEntropy"  0.202701
#    16.           "GrayLevelNonUniformity"  0.202268
#    17.                "LargeAreaEmphasis"  0.202213
#    18.                       "Uniformity"  0.201949
#    19.                      "TotalEnergy"  0.201285
#    20.               "InterquartileRange"  0.201181
#    21.                  "RootMeanSquared"  0.201133
#    22.                         "Kurtosis"  0.201121
#    23.                             "Mean"  0.201116
#    24.                           "Energy"  0.201068
#    25.                          "Minimum"  0.201060
#    26.                     "10Percentile"  0.201039
#    27.                         "Skewness"  0.201005
#    28.            "MeanAbsoluteDeviation"  0.201005
#    29.                         "Variance"  0.200986
#    30.                          "Entropy"  0.200947
#    31.                          "Maximum"  0.200942
#    32.                            "Range"  0.200940
#    33.                           "Median"  0.200930
#    34.                     "90Percentile"  0.200921
#
# Variable Importance: NUM_AS_ROOT:
#     1.      "HighGrayLevelZoneEmphasis" 184.000000 ################
#     2.  "LargeAreaLowGrayLevelEmphasis" 114.000000 #########
#     3.         "GrayLevelNonUniformity"  1.000000
#     4. "SmallAreaHighGrayLevelEmphasis"  1.000000
#
# Variable Importance: NUM_NODES:
#     1.                   "ZonePercentage" 636.000000 ################
#     2.    "LargeAreaLowGrayLevelEmphasis" 562.000000 ##############
#     3.   "LargeAreaHighGrayLevelEmphasis" 547.000000 #############
#     4.                "GrayLevelVariance" 493.000000 ############
#     5.        "HighGrayLevelZoneEmphasis" 290.000000 #######
#     6.   "SmallAreaHighGrayLevelEmphasis" 272.000000 ######
#     7.    "SmallAreaLowGrayLevelEmphasis" 250.000000 ######
#     8.  "SizeZoneNonUniformityNormalized" 136.000000 ###
#     9.                "SmallAreaEmphasis" 110.000000 ##
#    10.         "LowGrayLevelZoneEmphasis" 77.000000 #
#    11. "GrayLevelNonUniformityNormalized" 69.000000 #
#    12.                     "ZoneVariance" 65.000000 #
#    13.      "RobustMeanAbsoluteDeviation" 54.000000 #
#    14.            "SizeZoneNonUniformity" 49.000000 #
#    15.                      "ZoneEntropy" 49.000000 #
#    16.                "LargeAreaEmphasis" 35.000000
#    17.                       "Uniformity" 34.000000
#    18.           "GrayLevelNonUniformity" 33.000000
#    19.                          "Minimum" 22.000000
#    20.                           "Energy" 20.000000
#    21.            "MeanAbsoluteDeviation" 18.000000
#    22.                         "Variance" 18.000000
#    23.                             "Mean" 17.000000
#    24.                      "TotalEnergy" 17.000000
#    25.                     "10Percentile" 16.000000
#    26.                  "RootMeanSquared" 15.000000
#    27.               "InterquartileRange"  9.000000
#    28.                           "Median"  8.000000
#    29.                            "Range"  8.000000
#    30.                         "Skewness"  8.000000
#    31.                     "90Percentile"  7.000000
#    32.                          "Entropy"  7.000000
#    33.                         "Kurtosis"  7.000000
#    34.                          "Maximum"  7.000000
#
# Variable Importance: SUM_SCORE:
#     1.    "LargeAreaLowGrayLevelEmphasis" 1686.515859 ################
#     2.         "LowGrayLevelZoneEmphasis" 218.517522 ##
#     3.        "HighGrayLevelZoneEmphasis"  0.000002
#     4.                "GrayLevelVariance"  0.000001
#     5.   "SmallAreaHighGrayLevelEmphasis"  0.000001
#     6.    "SmallAreaLowGrayLevelEmphasis"  0.000000
#     7.                   "ZonePercentage"  0.000000
#     8. "GrayLevelNonUniformityNormalized"  0.000000
#     9.   "LargeAreaHighGrayLevelEmphasis"  0.000000
#    10.      "RobustMeanAbsoluteDeviation"  0.000000
#    11.           "GrayLevelNonUniformity"  0.000000
#    12.            "SizeZoneNonUniformity"  0.000000
#    13.  "SizeZoneNonUniformityNormalized"  0.000000
#    14.                "SmallAreaEmphasis"  0.000000
#    15.                      "ZoneEntropy"  0.000000
#    16.                       "Uniformity"  0.000000
#    17.                "LargeAreaEmphasis"  0.000000
#    18.            "MeanAbsoluteDeviation"  0.000000
#    19.                         "Variance"  0.000000
#    20.                          "Minimum"  0.000000
#    21.                     "ZoneVariance"  0.000000
#    22.                     "10Percentile"  0.000000
#    23.                           "Energy"  0.000000
#    24.                             "Mean"  0.000000
#    25.                  "RootMeanSquared"  0.000000
#    26.                      "TotalEnergy"  0.000000
#    27.                     "90Percentile"  0.000000
#    28.                           "Median"  0.000000
#    29.               "InterquartileRange"  0.000000
#    30.                         "Skewness"  0.000000
#    31.                         "Kurtosis"  0.000000
#    32.                          "Entropy"  0.000000
#    33.                          "Maximum"  0.000000
#    34.                            "Range"  0.000000
#
#
#
# Loss: BINOMIAL_LOG_LIKELIHOOD
# Validation loss value: 1.24159e-06
# Number of trees per iteration: 1
# Node format: NOT_SET
# Number of trees: 300
# Total number of nodes: 8230
#
# Number of nodes by tree:
# Count: 300 Average: 27.4333 StdDev: 8.82188
# Min: 11 Max: 51 Ignored: 0
# ----------------------------------------------
# [ 11, 13)   8   2.67%   2.67%
# [ 13, 15)  16   5.33%   8.00% #
# [ 15, 17)  28   9.33%  17.33% ##
# [ 17, 19)  14   4.67%  22.00% #
# [ 19, 21)   7   2.33%  24.33%
# [ 21, 23)   3   1.00%  25.33%
# [ 23, 25)   2   0.67%  26.00%
# [ 25, 27)   1   0.33%  26.33%
# [ 27, 29)   0   0.00%  26.33%
# [ 29, 31) 173  57.67%  84.00% ##########
# [ 31, 33)   1   0.33%  84.33%
# [ 33, 35)   4   1.33%  85.67%
# [ 35, 37)   8   2.67%  88.33%
# [ 37, 39)   4   1.33%  89.67%
# [ 39, 41)   1   0.33%  90.00%
# [ 41, 43)   0   0.00%  90.00%
# [ 43, 45)  10   3.33%  93.33% #
# [ 45, 47)   7   2.33%  95.67%
# [ 47, 49)  11   3.67%  99.33% #
# [ 49, 51]   2   0.67% 100.00%
#
# Depth by leafs:
# Count: 4265 Average: 4.1374 StdDev: 0.922239
# Min: 2 Max: 5 Ignored: 0
# ----------------------------------------------
# [ 2, 3)   95   2.23%   2.23%
# [ 3, 4) 1276  29.92%  32.15% ######
# [ 4, 5)  842  19.74%  51.89% ####
# [ 5, 5] 2052  48.11% 100.00% ##########
#
# Number of training obs by leaf:
# Count: 4265 Average: 99.6014 StdDev: 213.454
# Min: 5 Max: 1154 Ignored: 0
# ----------------------------------------------
# [    5,   62) 3283  76.98%  76.98% ##########
# [   62,  120)  106   2.49%  79.46%
# [  120,  177)  269   6.31%  85.77% #
# [  177,  235)   19   0.45%  86.21%
# [  235,  292)   49   1.15%  87.36%
# [  292,  350)   76   1.78%  89.14%
# [  350,  407)  161   3.77%  92.92%
# [  407,  465)    1   0.02%  92.94%
# [  465,  522)    3   0.07%  93.01%
# [  522,  580)    2   0.05%  93.06%
# [  580,  637)   18   0.42%  93.48%
# [  637,  695)    9   0.21%  93.69%
# [  695,  752)   19   0.45%  94.14%
# [  752,  810)   34   0.80%  94.94%
# [  810,  867)  193   4.53%  99.46% #
# [  867,  925)    9   0.21%  99.67%
# [  925,  982)    0   0.00%  99.67%
# [  982, 1040)    0   0.00%  99.67%
# [ 1040, 1097)    0   0.00%  99.67%
# [ 1097, 1154]   14   0.33% 100.00%
#
# Attribute in nodes:
# 	636 : ZonePercentage [NUMERICAL]
# 	562 : LargeAreaLowGrayLevelEmphasis [NUMERICAL]
# 	547 : LargeAreaHighGrayLevelEmphasis [NUMERICAL]
# 	493 : GrayLevelVariance [NUMERICAL]
# 	290 : HighGrayLevelZoneEmphasis [NUMERICAL]
# 	272 : SmallAreaHighGrayLevelEmphasis [NUMERICAL]
# 	250 : SmallAreaLowGrayLevelEmphasis [NUMERICAL]
# 	136 : SizeZoneNonUniformityNormalized [NUMERICAL]
# 	110 : SmallAreaEmphasis [NUMERICAL]
# 	77 : LowGrayLevelZoneEmphasis [NUMERICAL]
# 	69 : GrayLevelNonUniformityNormalized [NUMERICAL]
# 	65 : ZoneVariance [NUMERICAL]
# 	54 : RobustMeanAbsoluteDeviation [NUMERICAL]
# 	49 : ZoneEntropy [NUMERICAL]
# 	49 : SizeZoneNonUniformity [NUMERICAL]
# 	35 : LargeAreaEmphasis [NUMERICAL]
# 	34 : Uniformity [NUMERICAL]
# 	33 : GrayLevelNonUniformity [NUMERICAL]
# 	22 : Minimum [NUMERICAL]
# 	20 : Energy [NUMERICAL]
# 	18 : Variance [NUMERICAL]
# 	18 : MeanAbsoluteDeviation [NUMERICAL]
# 	17 : TotalEnergy [NUMERICAL]
# 	17 : Mean [NUMERICAL]
# 	16 : 10Percentile [NUMERICAL]
# 	15 : RootMeanSquared [NUMERICAL]
# 	9 : InterquartileRange [NUMERICAL]
# 	8 : Skewness [NUMERICAL]
# 	8 : Range [NUMERICAL]
# 	8 : Median [NUMERICAL]
# 	7 : Maximum [NUMERICAL]
# 	7 : Kurtosis [NUMERICAL]
# 	7 : Entropy [NUMERICAL]
# 	7 : 90Percentile [NUMERICAL]
#
# Attribute in nodes with depth <= 0:
# 	184 : HighGrayLevelZoneEmphasis [NUMERICAL]
# 	114 : LargeAreaLowGrayLevelEmphasis [NUMERICAL]
# 	1 : SmallAreaHighGrayLevelEmphasis [NUMERICAL]
# 	1 : GrayLevelNonUniformity [NUMERICAL]
#
# Attribute in nodes with depth <= 1:
# 	231 : HighGrayLevelZoneEmphasis [NUMERICAL]
# 	188 : ZonePercentage [NUMERICAL]
# 	181 : GrayLevelVariance [NUMERICAL]
# 	177 : LargeAreaLowGrayLevelEmphasis [NUMERICAL]
# 	58 : LowGrayLevelZoneEmphasis [NUMERICAL]
# 	13 : SmallAreaLowGrayLevelEmphasis [NUMERICAL]
# 	9 : SmallAreaHighGrayLevelEmphasis [NUMERICAL]
# 	8 : ZoneVariance [NUMERICAL]
# 	5 : SmallAreaEmphasis [NUMERICAL]
# 	5 : SizeZoneNonUniformityNormalized [NUMERICAL]
# 	5 : SizeZoneNonUniformity [NUMERICAL]
# 	5 : LargeAreaHighGrayLevelEmphasis [NUMERICAL]
# 	5 : LargeAreaEmphasis [NUMERICAL]
# 	5 : GrayLevelNonUniformity [NUMERICAL]
# 	3 : ZoneEntropy [NUMERICAL]
# 	2 : GrayLevelNonUniformityNormalized [NUMERICAL]
#
# Attribute in nodes with depth <= 2:
# 	562 : ZonePercentage [NUMERICAL]
# 	250 : GrayLevelVariance [NUMERICAL]
# 	245 : HighGrayLevelZoneEmphasis [NUMERICAL]
# 	203 : LargeAreaHighGrayLevelEmphasis [NUMERICAL]
# 	190 : LargeAreaLowGrayLevelEmphasis [NUMERICAL]
# 	189 : SmallAreaHighGrayLevelEmphasis [NUMERICAL]
# 	70 : LowGrayLevelZoneEmphasis [NUMERICAL]
# 	33 : GrayLevelNonUniformityNormalized [NUMERICAL]
# 	28 : SmallAreaLowGrayLevelEmphasis [NUMERICAL]
# 	27 : RobustMeanAbsoluteDeviation [NUMERICAL]
# 	24 : ZoneEntropy [NUMERICAL]
# 	20 : ZoneVariance [NUMERICAL]
# 	19 : LargeAreaEmphasis [NUMERICAL]
# 	18 : SizeZoneNonUniformity [NUMERICAL]
# 	16 : SizeZoneNonUniformityNormalized [NUMERICAL]
# 	14 : SmallAreaEmphasis [NUMERICAL]
# 	10 : GrayLevelNonUniformity [NUMERICAL]
# 	8 : Mean [NUMERICAL]
# 	7 : RootMeanSquared [NUMERICAL]
# 	6 : Skewness [NUMERICAL]
# 	6 : Range [NUMERICAL]
# 	6 : Median [NUMERICAL]
# 	6 : Kurtosis [NUMERICAL]
# 	6 : InterquartileRange [NUMERICAL]
# 	6 : Entropy [NUMERICAL]
# 	5 : TotalEnergy [NUMERICAL]
# 	5 : Maximum [NUMERICAL]
# 	5 : 10Percentile [NUMERICAL]
# 	4 : Variance [NUMERICAL]
# 	4 : Minimum [NUMERICAL]
# 	4 : MeanAbsoluteDeviation [NUMERICAL]
# 	4 : Energy [NUMERICAL]
# 	3 : 90Percentile [NUMERICAL]
# 	2 : Uniformity [NUMERICAL]
#
# Attribute in nodes with depth <= 3:
# 	603 : ZonePercentage [NUMERICAL]
# 	376 : LargeAreaLowGrayLevelEmphasis [NUMERICAL]
# 	364 : LargeAreaHighGrayLevelEmphasis [NUMERICAL]
# 	303 : GrayLevelVariance [NUMERICAL]
# 	274 : HighGrayLevelZoneEmphasis [NUMERICAL]
# 	230 : SmallAreaHighGrayLevelEmphasis [NUMERICAL]
# 	118 : SizeZoneNonUniformityNormalized [NUMERICAL]
# 	89 : SmallAreaEmphasis [NUMERICAL]
# 	75 : LowGrayLevelZoneEmphasis [NUMERICAL]
# 	65 : SmallAreaLowGrayLevelEmphasis [NUMERICAL]
# 	60 : ZoneVariance [NUMERICAL]
# 	48 : GrayLevelNonUniformityNormalized [NUMERICAL]
# 	45 : SizeZoneNonUniformity [NUMERICAL]
# 	35 : ZoneEntropy [NUMERICAL]
# 	32 : RobustMeanAbsoluteDeviation [NUMERICAL]
# 	28 : Uniformity [NUMERICAL]
# 	27 : LargeAreaEmphasis [NUMERICAL]
# 	16 : Mean [NUMERICAL]
# 	16 : GrayLevelNonUniformity [NUMERICAL]
# 	16 : Energy [NUMERICAL]
# 	14 : TotalEnergy [NUMERICAL]
# 	13 : RootMeanSquared [NUMERICAL]
# 	13 : 10Percentile [NUMERICAL]
# 	8 : Skewness [NUMERICAL]
# 	8 : Range [NUMERICAL]
# 	8 : Median [NUMERICAL]
# 	8 : InterquartileRange [NUMERICAL]
# 	7 : Minimum [NUMERICAL]
# 	7 : Maximum [NUMERICAL]
# 	7 : Kurtosis [NUMERICAL]
# 	7 : Entropy [NUMERICAL]
# 	7 : 90Percentile [NUMERICAL]
# 	6 : Variance [NUMERICAL]
# 	6 : MeanAbsoluteDeviation [NUMERICAL]
#
# Attribute in nodes with depth <= 5:
# 	636 : ZonePercentage [NUMERICAL]
# 	562 : LargeAreaLowGrayLevelEmphasis [NUMERICAL]
# 	547 : LargeAreaHighGrayLevelEmphasis [NUMERICAL]
# 	493 : GrayLevelVariance [NUMERICAL]
# 	290 : HighGrayLevelZoneEmphasis [NUMERICAL]
# 	272 : SmallAreaHighGrayLevelEmphasis [NUMERICAL]
# 	250 : SmallAreaLowGrayLevelEmphasis [NUMERICAL]
# 	136 : SizeZoneNonUniformityNormalized [NUMERICAL]
# 	110 : SmallAreaEmphasis [NUMERICAL]
# 	77 : LowGrayLevelZoneEmphasis [NUMERICAL]
# 	69 : GrayLevelNonUniformityNormalized [NUMERICAL]
# 	65 : ZoneVariance [NUMERICAL]
# 	54 : RobustMeanAbsoluteDeviation [NUMERICAL]
# 	49 : ZoneEntropy [NUMERICAL]
# 	49 : SizeZoneNonUniformity [NUMERICAL]
# 	35 : LargeAreaEmphasis [NUMERICAL]
# 	34 : Uniformity [NUMERICAL]
# 	33 : GrayLevelNonUniformity [NUMERICAL]
# 	22 : Minimum [NUMERICAL]
# 	20 : Energy [NUMERICAL]
# 	18 : Variance [NUMERICAL]
# 	18 : MeanAbsoluteDeviation [NUMERICAL]
# 	17 : TotalEnergy [NUMERICAL]
# 	17 : Mean [NUMERICAL]
# 	16 : 10Percentile [NUMERICAL]
# 	15 : RootMeanSquared [NUMERICAL]
# 	9 : InterquartileRange [NUMERICAL]
# 	8 : Skewness [NUMERICAL]
# 	8 : Range [NUMERICAL]
# 	8 : Median [NUMERICAL]
# 	7 : Maximum [NUMERICAL]
# 	7 : Kurtosis [NUMERICAL]
# 	7 : Entropy [NUMERICAL]
# 	7 : 90Percentile [NUMERICAL]
#
# Condition type in nodes:
# 	3965 : HigherCondition
# Condition type in nodes with depth <= 0:
# 	300 : HigherCondition
# Condition type in nodes with depth <= 1:
# 	900 : HigherCondition
# Condition type in nodes with depth <= 2:
# 	2005 : HigherCondition
# Condition type in nodes with depth <= 3:
# 	2939 : HigherCondition
# Condition type in nodes with depth <= 5:
# 	3965 : HigherCondition
#
# Training logs:
# Number of iteration to final model: 300
# 	Iter:1 train-loss:1.196273 valid-loss:1.196366  train-accuracy:1.000000 valid-accuracy:1.000000
# 	Iter:2 train-loss:1.040654 valid-loss:1.040731  train-accuracy:1.000000 valid-accuracy:1.000000
# 	Iter:3 train-loss:0.910885 valid-loss:0.910949  train-accuracy:1.000000 valid-accuracy:1.000000
# 	Iter:4 train-loss:0.801193 valid-loss:0.801248  train-accuracy:1.000000 valid-accuracy:1.000000
# 	Iter:5 train-loss:0.707491 valid-loss:0.707538  train-accuracy:1.000000 valid-accuracy:1.000000
# 	Iter:6 train-loss:0.626773 valid-loss:0.626814  train-accuracy:1.000000 valid-accuracy:1.000000
# 	Iter:16 train-loss:0.206083 valid-loss:0.206095  train-accuracy:1.000000 valid-accuracy:1.000000
# 	Iter:26 train-loss:0.073115 valid-loss:0.073119  train-accuracy:1.000000 valid-accuracy:1.000000
# 	Iter:36 train-loss:0.026556 valid-loss:0.026557  train-accuracy:1.000000 valid-accuracy:1.000000
# 	Iter:46 train-loss:0.009724 valid-loss:0.009725  train-accuracy:1.000000 valid-accuracy:1.000000
# 	Iter:56 train-loss:0.003571 valid-loss:0.003571  train-accuracy:1.000000 valid-accuracy:1.000000
# 	Iter:66 train-loss:0.001313 valid-loss:0.001313  train-accuracy:1.000000 valid-accuracy:1.000000
# 	Iter:76 train-loss:0.000483 valid-loss:0.000483  train-accuracy:1.000000 valid-accuracy:1.000000
# 	Iter:86 train-loss:0.000179 valid-loss:0.000181  train-accuracy:1.000000 valid-accuracy:1.000000
# 	Iter:96 train-loss:0.000069 valid-loss:0.000071  train-accuracy:1.000000 valid-accuracy:1.000000
# 	Iter:106 train-loss:0.000029 valid-loss:0.000031  train-accuracy:1.000000 valid-accuracy:1.000000
# 	Iter:116 train-loss:0.000014 valid-loss:0.000016  train-accuracy:1.000000 valid-accuracy:1.000000
# 	Iter:126 train-loss:0.000008 valid-loss:0.000009  train-accuracy:1.000000 valid-accuracy:1.000000
# 	Iter:136 train-loss:0.000005 valid-loss:0.000006  train-accuracy:1.000000 valid-accuracy:1.000000
# 	Iter:146 train-loss:0.000003 valid-loss:0.000004  train-accuracy:1.000000 valid-accuracy:1.000000
# 	Iter:156 train-loss:0.000003 valid-loss:0.000004  train-accuracy:1.000000 valid-accuracy:1.000000
# 	Iter:166 train-loss:0.000002 valid-loss:0.000003  train-accuracy:1.000000 valid-accuracy:1.000000
# 	Iter:176 train-loss:0.000002 valid-loss:0.000003  train-accuracy:1.000000 valid-accuracy:1.000000
# 	Iter:186 train-loss:0.000002 valid-loss:0.000003  train-accuracy:1.000000 valid-accuracy:1.000000
# 	Iter:196 train-loss:0.000002 valid-loss:0.000002  train-accuracy:1.000000 valid-accuracy:1.000000
# 	Iter:206 train-loss:0.000002 valid-loss:0.000002  train-accuracy:1.000000 valid-accuracy:1.000000
# 	Iter:216 train-loss:0.000001 valid-loss:0.000002  train-accuracy:1.000000 valid-accuracy:1.000000
# 	Iter:226 train-loss:0.000001 valid-loss:0.000002  train-accuracy:1.000000 valid-accuracy:1.000000
# 	Iter:236 train-loss:0.000001 valid-loss:0.000002  train-accuracy:1.000000 valid-accuracy:1.000000
# 	Iter:246 train-loss:0.000001 valid-loss:0.000002  train-accuracy:1.000000 valid-accuracy:1.000000
# 	Iter:256 train-loss:0.000001 valid-loss:0.000002  train-accuracy:1.000000 valid-accuracy:1.000000
# 	Iter:266 train-loss:0.000001 valid-loss:0.000001  train-accuracy:1.000000 valid-accuracy:1.000000
# 	Iter:276 train-loss:0.000001 valid-loss:0.000001  train-accuracy:1.000000 valid-accuracy:1.000000
# 	Iter:286 train-loss:0.000001 valid-loss:0.000001  train-accuracy:1.000000 valid-accuracy:1.000000
# 	Iter:296 train-loss:0.000001 valid-loss:0.000001  train-accuracy:1.000000 valid-accuracy:1.000000

# %%
# Model features
model.make_inspector().features()
# Out:
# ["10Percentile" (1; #0),
#  "90Percentile" (1; #1),
#  "Energy" (1; #2),
#  "Entropy" (1; #3),
#  "GrayLevelNonUniformity" (1; #4),
#  "GrayLevelNonUniformityNormalized" (1; #5),
#  "GrayLevelVariance" (1; #6),
#  "HighGrayLevelZoneEmphasis" (1; #7),
#  "InterquartileRange" (1; #8),
#  "Kurtosis" (1; #9),
#  "LargeAreaEmphasis" (1; #10),
#  "LargeAreaHighGrayLevelEmphasis" (1; #11),
#  "LargeAreaLowGrayLevelEmphasis" (1; #12),
#  "LowGrayLevelZoneEmphasis" (1; #13),
#  "Maximum" (1; #14),
#  "Mean" (1; #15),
#  "MeanAbsoluteDeviation" (1; #16),
#  "Median" (1; #17),
#  "Minimum" (1; #18),
#  "Range" (1; #19),
#  "RobustMeanAbsoluteDeviation" (1; #20),
#  "RootMeanSquared" (1; #21),
#  "SizeZoneNonUniformity" (1; #22),
#  "SizeZoneNonUniformityNormalized" (1; #23),
#  "Skewness" (1; #24),
#  "SmallAreaEmphasis" (1; #25),
#  "SmallAreaHighGrayLevelEmphasis" (1; #26),
#  "SmallAreaLowGrayLevelEmphasis" (1; #27),
#  "TotalEnergy" (1; #28),
#  "Uniformity" (1; #29),
#  "Variance" (1; #30),
#  "ZoneEntropy" (1; #31),
#  "ZonePercentage" (1; #32),
#  "ZoneVariance" (1; #33)]

# %%
# Feature importance
model.make_inspector().variable_importances()
# Out:
# {'INV_MEAN_MIN_DEPTH': [("HighGrayLevelZoneEmphasis" (1; #7),
#    0.4672719780090088),
#   ("LargeAreaLowGrayLevelEmphasis" (1; #12), 0.30457312842436673),
#   ("ZonePercentage" (1; #32), 0.2643411795593763),
#   ("GrayLevelVariance" (1; #6), 0.25955873228998844),
#   ("SmallAreaHighGrayLevelEmphasis" (1; #26), 0.22756733768521692),
#   ("LowGrayLevelZoneEmphasis" (1; #13), 0.2139458984342432),
#   ("LargeAreaHighGrayLevelEmphasis" (1; #11), 0.21260543729010206),
#   ("SizeZoneNonUniformityNormalized" (1; #23), 0.2091438515175949),
#   ("SmallAreaLowGrayLevelEmphasis" (1; #27), 0.20867828129831012),
#   ("SmallAreaEmphasis" (1; #25), 0.2070551187239687),
#   ("GrayLevelNonUniformityNormalized" (1; #5), 0.20444945179157967),
#   ("SizeZoneNonUniformity" (1; #22), 0.20387528002184382),
#   ("RobustMeanAbsoluteDeviation" (1; #20), 0.20356696196539778),
#   ("ZoneVariance" (1; #33), 0.20304414139014434),
#   ("ZoneEntropy" (1; #31), 0.2027011855712318),
#   ("GrayLevelNonUniformity" (1; #4), 0.20226805497953063),
#   ("LargeAreaEmphasis" (1; #10), 0.20221275534578306),
#   ("Uniformity" (1; #29), 0.20194939089162148),
#   ("TotalEnergy" (1; #28), 0.20128483512553952),
#   ("InterquartileRange" (1; #8), 0.2011811363297469),
#   ("RootMeanSquared" (1; #21), 0.20113314492894907),
#   ("Kurtosis" (1; #9), 0.20112109565529313),
#   ("Mean" (1; #15), 0.20111582038091982),
#   ("Energy" (1; #2), 0.20106782062346396),
#   ("Minimum" (1; #18), 0.20106017268931464),
#   ("10Percentile" (1; #0), 0.2010387258663001),
#   ("Skewness" (1; #24), 0.20100508218683497),
#   ("MeanAbsoluteDeviation" (1; #16), 0.2010046810345132),
#   ("Variance" (1; #30), 0.20098574328195393),
#   ("Entropy" (1; #3), 0.20094672375125985),
#   ("Maximum" (1; #14), 0.200942343764763),
#   ("Range" (1; #19), 0.20094037710598506),
#   ("Median" (1; #17), 0.2009296959184534),
#   ("90Percentile" (1; #1), 0.20092128547686172)],
#  'NUM_AS_ROOT': [("HighGrayLevelZoneEmphasis" (1; #7), 184.0),
#   ("LargeAreaLowGrayLevelEmphasis" (1; #12), 114.0),
#   ("GrayLevelNonUniformity" (1; #4), 1.0),
#   ("SmallAreaHighGrayLevelEmphasis" (1; #26), 1.0)],
#  'SUM_SCORE': [("LargeAreaLowGrayLevelEmphasis" (1; #12), 1686.5158589919156),
#   ("LowGrayLevelZoneEmphasis" (1; #13), 218.51752226356467),
#   ("HighGrayLevelZoneEmphasis" (1; #7), 2.1526875538274845e-06),
#   ("GrayLevelVariance" (1; #6), 1.3997815111441662e-06),
#   ("SmallAreaHighGrayLevelEmphasis" (1; #26), 6.124263692321553e-07),
#   ("SmallAreaLowGrayLevelEmphasis" (1; #27), 4.4855504985769426e-07),
#   ("ZonePercentage" (1; #32), 3.41696224252751e-07),
#   ("GrayLevelNonUniformityNormalized" (1; #5), 2.1270847673477038e-07),
#   ("LargeAreaHighGrayLevelEmphasis" (1; #11), 1.1984427585039394e-07),
#   ("RobustMeanAbsoluteDeviation" (1; #20), 1.1459686931794225e-07),
#   ("GrayLevelNonUniformity" (1; #4), 1.1444699902904605e-07),
#   ("SizeZoneNonUniformity" (1; #22), 3.034125933830903e-08),
#   ("SizeZoneNonUniformityNormalized" (1; #23), 2.9173812058146575e-08),
#   ("SmallAreaEmphasis" (1; #25), 2.1624922743639545e-08),
#   ("ZoneEntropy" (1; #31), 2.056901641167448e-08),
#   ("Uniformity" (1; #29), 2.009718144703063e-08),
#   ("LargeAreaEmphasis" (1; #10), 1.0044000092061727e-08),
#   ("MeanAbsoluteDeviation" (1; #16), 8.502432809739342e-09),
#   ("Variance" (1; #30), 7.377580330100444e-09),
#   ("Minimum" (1; #18), 6.704996466032397e-09),
#   ("ZoneVariance" (1; #33), 5.245559704129091e-09),
#   ("10Percentile" (1; #0), 1.635315008023821e-09),
#   ("Energy" (1; #2), 1.548348966291192e-09),
#   ("Mean" (1; #15), 1.0298859188352783e-09),
#   ("RootMeanSquared" (1; #21), 8.615488824646399e-10),
#   ("TotalEnergy" (1; #28), 6.213685100871564e-10),
#   ("90Percentile" (1; #1), 4.875072808251505e-10),
#   ("Median" (1; #17), 3.8760665609983726e-14),
#   ("InterquartileRange" (1; #8), 1.6654018905686727e-14),
#   ("Skewness" (1; #24), 1.3024443393835345e-14),
#   ("Kurtosis" (1; #9), 1.1702451757581479e-14),
#   ("Entropy" (1; #3), 1.1106377980843974e-14),
#   ("Maximum" (1; #14), 1.4577443000507761e-15),
#   ("Range" (1; #19), 5.638329769306264e-16)],
#  'NUM_NODES': [("ZonePercentage" (1; #32), 636.0),
#   ("LargeAreaLowGrayLevelEmphasis" (1; #12), 562.0),
#   ("LargeAreaHighGrayLevelEmphasis" (1; #11), 547.0),
#   ("GrayLevelVariance" (1; #6), 493.0),
#   ("HighGrayLevelZoneEmphasis" (1; #7), 290.0),
#   ("SmallAreaHighGrayLevelEmphasis" (1; #26), 272.0),
#   ("SmallAreaLowGrayLevelEmphasis" (1; #27), 250.0),
#   ("SizeZoneNonUniformityNormalized" (1; #23), 136.0),
#   ("SmallAreaEmphasis" (1; #25), 110.0),
#   ("LowGrayLevelZoneEmphasis" (1; #13), 77.0),
#   ("GrayLevelNonUniformityNormalized" (1; #5), 69.0),
#   ("ZoneVariance" (1; #33), 65.0),
#   ("RobustMeanAbsoluteDeviation" (1; #20), 54.0),
#   ("SizeZoneNonUniformity" (1; #22), 49.0),
#   ("ZoneEntropy" (1; #31), 49.0),
#   ("LargeAreaEmphasis" (1; #10), 35.0),
#   ("Uniformity" (1; #29), 34.0),
#   ("GrayLevelNonUniformity" (1; #4), 33.0),
#   ("Minimum" (1; #18), 22.0),
#   ("Energy" (1; #2), 20.0),
#   ("MeanAbsoluteDeviation" (1; #16), 18.0),
#   ("Variance" (1; #30), 18.0),
#   ("Mean" (1; #15), 17.0),
#   ("TotalEnergy" (1; #28), 17.0),
#   ("10Percentile" (1; #0), 16.0),
#   ("RootMeanSquared" (1; #21), 15.0),
#   ("InterquartileRange" (1; #8), 9.0),
#   ("Median" (1; #17), 8.0),
#   ("Range" (1; #19), 8.0),
#   ("Skewness" (1; #24), 8.0),
#   ("90Percentile" (1; #1), 7.0),
#   ("Entropy" (1; #3), 7.0),
#   ("Kurtosis" (1; #9), 7.0),
#   ("Maximum" (1; #14), 7.0)]}

# %%
# Model self evaluation
model.make_inspector().evaluation()
# Out:
# Evaluation(num_examples=None, accuracy=1.0, loss=1.2415912351571023e-06, rmse=None, ndcg=None, aucs=None, auuc=None, qini=None)

# %%
logs = model.make_inspector().training_logs()

plt.figure(figsize=(12, 4))
plt.subplot(1, 2, 1)
plt.plot([log.num_trees for log in logs], [log.evaluation.accuracy for log in logs])
plt.xlabel("Number of trees")
plt.ylabel("Accuracy (out-of-bag)")
plt.subplot(1, 2, 2)
plt.plot([log.num_trees for log in logs], [log.evaluation.loss for log in logs])
plt.xlabel("Number of trees")
plt.ylabel("Logloss (out-of-bag)")
plt.show()

# %% [markdown]
# Calculate the score of our hold-out validation dataset

# %%
predictions = model.predict(val_ds)
y_true      = validation_data["label"]

from sklearn.metrics import roc_auc_score
ROC_AUC = roc_auc_score(y_true, predictions)
print("The ROC AUC score is %.5f" % ROC_AUC )
# Out:
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 1s 1s/step
# The ROC AUC score is 1.00000

# %%
# Compute binary classification metrics with sklearn
import numpy as np
from sklearn.metrics import (
    accuracy_score,
    precision_score,
    recall_score,
    f1_score,
    roc_auc_score,
    average_precision_score,
    confusion_matrix,
    classification_report,
    matthews_corrcoef,
    log_loss,
    brier_score_loss,
)

# Get predictions (probabilities or class labels)
preds = model.predict(test_ds)
# If model outputs probabilities, convert to labels by threshold 0.5
if preds.ndim == 2:
    # For TFDF classification, preds may be class probabilities with shape (N, 2)
    if preds.shape[1] == 2:
        pos_probs = preds[:, 1]
    else:
        # If single-probability column (positive class)
        pos_probs = preds[:, -1]
    y_pred = (pos_probs >= 0.5).astype(int)
else:
    # Already class labels
    y_pred = preds.astype(int)
    pos_probs = None

# Ground truth labels (must be 0/1 integers)
y_true = test_data["label"].astype(int).to_numpy()

# Core metrics
metrics = {}
metrics["accuracy"] = accuracy_score(y_true, y_pred)
metrics["precision"] = precision_score(y_true, y_pred, zero_division=0)
metrics["recall"] = recall_score(y_true, y_pred, zero_division=0)
metrics["f1"] = f1_score(y_true, y_pred, zero_division=0)
metrics["mcc"] = matthews_corrcoef(y_true, y_pred)

# Probabilistic metrics (only if we have probabilities)
if pos_probs is not None:
    metrics["roc_auc"] = roc_auc_score(y_true, pos_probs)
    metrics["pr_auc"] = average_precision_score(y_true, pos_probs)
    metrics["log_loss"] = log_loss(y_true, pos_probs, labels=[0,1])
    metrics["brier_score"] = brier_score_loss(y_true, pos_probs)

# Confusion matrix and detailed report
cm = confusion_matrix(y_true, y_pred, labels=[0,1])
report = classification_report(y_true, y_pred, digits=4)

print("Sklearn binary metrics:")
for k, v in metrics.items():
    print(f"{k}: {v:.4f}")
print("\nConfusion matrix:\n", cm)
print("\nClassification report:\n", report)
# Out:
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 74ms/step
# Sklearn binary metrics:
# accuracy: 1.0000
# precision: 1.0000
# recall: 1.0000
# f1: 1.0000
# mcc: 1.0000
# roc_auc: 1.0000
# pr_auc: 1.0000
# log_loss: 0.0000
# brier_score: 0.0000
#
# Confusion matrix:
#  [[328   0]
#  [  0 114]]
#
# Classification report:
#                precision    recall  f1-score   support
#
#            0     1.0000    1.0000    1.0000       328
#            1     1.0000    1.0000    1.0000       114
#
#     accuracy                         1.0000       442
#    macro avg     1.0000    1.0000    1.0000       442
# weighted avg     1.0000    1.0000    1.0000       442
