# %%
# Import packages and modules
import numpy  as np
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow_decision_forests as tfdf

from sklearn.model_selection import train_test_split
# Out:
# 2026-08-15 05:13:16.550538: I tensorflow/core/util/port.cc:113] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2026-08-15 05:13:16.915554: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2026-08-15 05:13:21.755193: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
# Check the version of TensorFlow Decision Forests
print("Found TensorFlow Decision Forests v" + tfdf.__version__)
# Out:
# Found TensorFlow Decision Forests v1.9.1

# %%
datasetPath = 'dataset/firstorder/kernel5/dataset.csv'

# %%
# Parameters
datasetPath = "dataset/glcm/kernel4/1.dataset.csv"

# %%
# train/validation/test = 70/10/20
dataset = pd.read_csv(datasetPath)

train_data, temp_data = train_test_split(dataset, test_size=0.3, random_state=42)
validation_data, test_data = train_test_split(temp_data, test_size=2/3, random_state=42)

# %%
from sklearn.utils.class_weight import compute_class_weight

# tinh class weight tren tap train
classes = np.array([0, 1])
weights = compute_class_weight(class_weight="balanced", classes=classes, y=train_data["label"])
class_weight = {0: weights[0], 1: weights[1]}

# gan sample_weight cho tung dong
train_data["sample_weight"] = train_data["label"].map(class_weight)
validation_data["sample_weight"] = validation_data["label"].map(class_weight)
test_data["sample_weight"] = test_data["label"].map(class_weight)

# Convert the dataset into a TensorFlow dataset.
train_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    train_data, label="label", weight="sample_weight"
)         
val_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    validation_data, label="label", weight="sample_weight"
)
test_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    test_data, label="label", weight="sample_weight"
)
# Out:
# 2026-08-15 05:13:35.715569: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:984] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2026-08-15 05:13:35.717053: W tensorflow/core/common_runtime/gpu/gpu_device.cc:2251] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...

# %%
import keras

# %%
# %%time

# Train a Random Forest model.
model = tfdf.keras.RandomForestModel()

# Add evaluation metrics
model.compile(
    metrics=["accuracy"]
)
model.fit(x=train_ds)

# # Train a Gradient Boosted Trees model.
# model = tfdf.keras.GradientBoostedTreesModel(num_trees=1500)
# model.fit(train_ds)
# Out:
# Use /tmp/tmp52iyichw as temporary training directory
# Reading training dataset...
# Training dataset read in 0:00:02.674207. Found 1554 examples.
# Training model...
# Model trained in 0:00:00.073313
# Compiling model...
# [INFO 26-08-15 05:13:38.6364 UTC kernel.cc:1233] Loading model from path /tmp/tmp52iyichw/model/ with prefix 14678666230f4f36
# [INFO 26-08-15 05:13:38.6452 UTC decision_forest.cc:734] Model loaded with 300 root(s), 6968 node(s), and 24 input feature(s).
# [INFO 26-08-15 05:13:38.6452 UTC abstract_model.cc:1362] Engine "RandomForestOptPred" built
# [INFO 26-08-15 05:13:38.6453 UTC kernel.cc:1061] Use fast generic engine
# Model compiled.
# CPU times: user 5.75 s, sys: 70.4 ms, total: 5.82 s
# Wall time: 5.94 s

# %%
# Evaluate the model
evaluate = model.evaluate(val_ds, return_dict=True)
print()

for name, value in evaluate.items():
    print(f"{name}: {value:.4f}")
# Out:
# WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 1/1 [==============================] - ETA: 0s - loss: 0.0000e+00 - accuracy: 0.9910
# 1/1 [==============================] - 3s 3s/step - loss: 0.0000e+00 - accuracy: 0.9910
# loss: 0.0000
# accuracy: 0.9910

# %%
# Model Summary
model.summary()
# Out:
# Model: "random_forest_model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
# =================================================================
# Total params: 1 (1.00 Byte)
# Trainable params: 0 (0.00 Byte)
# Non-trainable params: 1 (1.00 Byte)
# _________________________________________________________________
# Type: "RANDOM_FOREST"
# Task: CLASSIFICATION
# Label: "__LABEL"
#
# Input Features (24):
# 	Autocorrelation
# 	ClusterProminence
# 	ClusterShade
# 	ClusterTendency
# 	Contrast
# 	Correlation
# 	DifferenceAverage
# 	DifferenceEntropy
# 	DifferenceVariance
# 	Id
# 	Idm
# 	Idmn
# 	Idn
# 	Imc1
# 	Imc2
# 	InverseVariance
# 	JointAverage
# 	JointEnergy
# 	JointEntropy
# 	MCC
# 	MaximumProbability
# 	SumAverage
# 	SumEntropy
# 	SumSquares
#
# Trained with weights
#
# Variable Importance: INV_MEAN_MIN_DEPTH:
#     1.    "Autocorrelation"  0.266428 ################
#     2.         "SumAverage"  0.265723 ###############
#     3.       "JointAverage"  0.260367 ##############
#     4.               "Imc2"  0.238125 #########
#     5.               "Imc1"  0.230236 #######
#     6.         "SumEntropy"  0.226149 ######
#     7.        "JointEnergy"  0.216146 ####
#     8.        "Correlation"  0.211073 ###
#     9. "MaximumProbability"  0.210656 ###
#    10.       "JointEntropy"  0.209529 ###
#    11.                "MCC"  0.208312 ##
#    12.       "ClusterShade"  0.205242 ##
#    13.  "ClusterProminence"  0.204913 #
#    14. "DifferenceVariance"  0.202966 #
#    15.    "ClusterTendency"  0.201885 #
#    16.               "Idmn"  0.200737 #
#    17.                "Idm"  0.199729
#    18.                 "Id"  0.199461
#    19.         "SumSquares"  0.199433
#    20.           "Contrast"  0.199276
#    21.    "InverseVariance"  0.197329
#    22.  "DifferenceAverage"  0.196980
#    23.                "Idn"  0.196321
#    24.  "DifferenceEntropy"  0.196265
#
# Variable Importance: NUM_AS_ROOT:
#     1.        "SumAverage" 61.000000 ################
#     2.   "Autocorrelation" 58.000000 ###############
#     3.      "JointAverage" 56.000000 ##############
#     4.              "Imc2" 29.000000 #######
#     5.              "Imc1" 22.000000 #####
#     6.        "SumEntropy" 22.000000 #####
#     7.       "JointEnergy" 14.000000 ###
#     8.      "JointEntropy" 14.000000 ###
#     9. "ClusterProminence"  9.000000 ##
#    10.               "MCC"  5.000000 #
#    11.   "ClusterTendency"  3.000000
#    12.        "SumSquares"  3.000000
#    13.                "Id"  2.000000
#    14.       "Correlation"  1.000000
#    15.               "Idm"  1.000000
#
# Variable Importance: NUM_NODES:
#     1.    "Autocorrelation" 366.000000 ################
#     2.       "JointAverage" 321.000000 #############
#     3.         "SumAverage" 311.000000 #############
#     4.               "Imc2" 238.000000 #########
#     5.               "Imc1" 201.000000 #######
#     6.         "SumEntropy" 189.000000 #######
#     7.        "Correlation" 170.000000 ######
#     8.        "JointEnergy" 165.000000 #####
#     9.       "ClusterShade" 158.000000 #####
#    10. "MaximumProbability" 142.000000 ####
#    11.                "MCC" 118.000000 ###
#    12.       "JointEntropy" 104.000000 ##
#    13.  "ClusterProminence" 92.000000 ##
#    14. "DifferenceVariance" 90.000000 ##
#    15.           "Contrast" 89.000000 ##
#    16.    "ClusterTendency" 75.000000 #
#    17.               "Idmn" 75.000000 #
#    18.  "DifferenceAverage" 70.000000 #
#    19.    "InverseVariance" 69.000000 #
#    20.                "Idm" 65.000000
#    21.         "SumSquares" 65.000000
#    22.                 "Id" 60.000000
#    23.                "Idn" 54.000000
#    24.  "DifferenceEntropy" 47.000000
#
# Variable Importance: SUM_SCORE:
#     1.    "Autocorrelation" 74132.051485 ################
#     2.         "SumAverage" 66160.768279 ##############
#     3.       "JointAverage" 64457.555290 #############
#     4.               "Imc2" 21078.721329 ####
#     5.         "SumEntropy" 17573.891134 ###
#     6.               "Imc1" 13126.778178 ##
#     7.        "JointEnergy" 10781.369959 ##
#     8.       "JointEntropy" 7779.663342 #
#     9. "MaximumProbability" 6355.077762 #
#    10.        "Correlation" 5489.928491 #
#    11.                "MCC" 4901.292011
#    12.  "ClusterProminence" 3848.490765
#    13.       "ClusterShade" 3638.777445
#    14. "DifferenceVariance" 2580.743049
#    15.    "ClusterTendency" 2294.197718
#    16.                 "Id" 2255.582813
#    17.                "Idm" 2024.980300
#    18.         "SumSquares" 1900.371012
#    19.               "Idmn" 1813.439109
#    20.           "Contrast" 1662.232203
#    21.    "InverseVariance" 1387.562829
#    22.  "DifferenceAverage" 1130.507032
#    23.  "DifferenceEntropy" 860.481775
#    24.                "Idn" 796.487363
#
#
#
# Winner takes all: true
# Out-of-bag evaluation: accuracy:0.944268 logloss:0.131796
# Number of trees: 300
# Total number of nodes: 6968
#
# Number of nodes by tree:
# Count: 300 Average: 23.2267 StdDev: 5.05193
# Min: 9 Max: 47 Ignored: 0
# ----------------------------------------------
# [  9, 10)  1   0.33%   0.33%
# [ 10, 12)  0   0.00%   0.33%
# [ 12, 14)  5   1.67%   2.00% #
# [ 14, 16) 10   3.33%   5.33% ##
# [ 16, 18) 16   5.33%  10.67% ###
# [ 18, 20) 44  14.67%  25.33% ########
# [ 20, 22) 56  18.67%  44.00% ##########
# [ 22, 24) 55  18.33%  62.33% ##########
# [ 24, 26) 39  13.00%  75.33% #######
# [ 26, 28) 28   9.33%  84.67% #####
# [ 28, 30) 19   6.33%  91.00% ###
# [ 30, 32) 13   4.33%  95.33% ##
# [ 32, 34)  4   1.33%  96.67% #
# [ 34, 36)  4   1.33%  98.00% #
# [ 36, 38)  2   0.67%  98.67%
# [ 38, 40)  3   1.00%  99.67% #
# [ 40, 42)  0   0.00%  99.67%
# [ 42, 44)  0   0.00%  99.67%
# [ 44, 46)  0   0.00%  99.67%
# [ 46, 47]  1   0.33% 100.00%
#
# Depth by leafs:
# Count: 3634 Average: 4.25922 StdDev: 1.51545
# Min: 1 Max: 10 Ignored: 0
# ----------------------------------------------
# [  1,  2)  11   0.30%   0.30%
# [  2,  3) 401  11.03%  11.34% ####
# [  3,  4) 852  23.45%  34.78% #########
# [  4,  5) 907  24.96%  59.74% ##########
# [  5,  6) 693  19.07%  78.81% ########
# [  6,  7) 476  13.10%  91.91% #####
# [  7,  8) 225   6.19%  98.10% ##
# [  8,  9)  42   1.16%  99.26%
# [  9, 10)  21   0.58%  99.83%
# [ 10, 10]   6   0.17% 100.00%
#
# Number of training obs by leaf:
# Count: 3634 Average: 128.288 StdDev: 313.105
# Min: 5 Max: 1431 Ignored: 0
# ----------------------------------------------
# [    5,   76) 2944  81.01%  81.01% ##########
# [   76,  147)  173   4.76%  85.77% #
# [  147,  219)   72   1.98%  87.75%
# [  219,  290)   54   1.49%  89.24%
# [  290,  361)   32   0.88%  90.12%
# [  361,  433)   19   0.52%  90.64%
# [  433,  504)   15   0.41%  91.06%
# [  504,  575)   11   0.30%  91.36%
# [  575,  647)   21   0.58%  91.94%
# [  647,  718)   26   0.72%  92.65%
# [  718,  789)   14   0.39%  93.04%
# [  789,  861)   14   0.39%  93.42%
# [  861,  932)   10   0.28%  93.70%
# [  932, 1003)   23   0.63%  94.33%
# [ 1003, 1075)   15   0.41%  94.74%
# [ 1075, 1146)   25   0.69%  95.43%
# [ 1146, 1217)   28   0.77%  96.20%
# [ 1217, 1289)   34   0.94%  97.14%
# [ 1289, 1360)   80   2.20%  99.34%
# [ 1360, 1431]   24   0.66% 100.00%
#
# Attribute in nodes:
# 	366 : Autocorrelation [NUMERICAL]
# 	321 : JointAverage [NUMERICAL]
# 	311 : SumAverage [NUMERICAL]
# 	238 : Imc2 [NUMERICAL]
# 	201 : Imc1 [NUMERICAL]
# 	189 : SumEntropy [NUMERICAL]
# 	170 : Correlation [NUMERICAL]
# 	165 : JointEnergy [NUMERICAL]
# 	158 : ClusterShade [NUMERICAL]
# 	142 : MaximumProbability [NUMERICAL]
# 	118 : MCC [NUMERICAL]
# 	104 : JointEntropy [NUMERICAL]
# 	92 : ClusterProminence [NUMERICAL]
# 	90 : DifferenceVariance [NUMERICAL]
# 	89 : Contrast [NUMERICAL]
# 	75 : Idmn [NUMERICAL]
# 	75 : ClusterTendency [NUMERICAL]
# 	70 : DifferenceAverage [NUMERICAL]
# 	69 : InverseVariance [NUMERICAL]
# 	65 : SumSquares [NUMERICAL]
# 	65 : Idm [NUMERICAL]
# 	60 : Id [NUMERICAL]
# 	54 : Idn [NUMERICAL]
# 	47 : DifferenceEntropy [NUMERICAL]
#
# Attribute in nodes with depth <= 0:
# 	61 : SumAverage [NUMERICAL]
# 	58 : Autocorrelation [NUMERICAL]
# 	56 : JointAverage [NUMERICAL]
# 	29 : Imc2 [NUMERICAL]
# 	22 : SumEntropy [NUMERICAL]
# 	22 : Imc1 [NUMERICAL]
# 	14 : JointEntropy [NUMERICAL]
# 	14 : JointEnergy [NUMERICAL]
# 	9 : ClusterProminence [NUMERICAL]
# 	5 : MCC [NUMERICAL]
# 	3 : SumSquares [NUMERICAL]
# 	3 : ClusterTendency [NUMERICAL]
# 	2 : Id [NUMERICAL]
# 	1 : Idm [NUMERICAL]
# 	1 : Correlation [NUMERICAL]
#
# Attribute in nodes with depth <= 1:
# 	148 : Autocorrelation [NUMERICAL]
# 	135 : JointAverage [NUMERICAL]
# 	119 : SumAverage [NUMERICAL]
# 	86 : Imc2 [NUMERICAL]
# 	71 : Imc1 [NUMERICAL]
# 	69 : SumEntropy [NUMERICAL]
# 	45 : JointEnergy [NUMERICAL]
# 	34 : JointEntropy [NUMERICAL]
# 	26 : MaximumProbability [NUMERICAL]
# 	25 : MCC [NUMERICAL]
# 	24 : Correlation [NUMERICAL]
# 	20 : ClusterTendency [NUMERICAL]
# 	18 : ClusterProminence [NUMERICAL]
# 	13 : Id [NUMERICAL]
# 	11 : Idm [NUMERICAL]
# 	11 : DifferenceVariance [NUMERICAL]
# 	9 : SumSquares [NUMERICAL]
# 	7 : ClusterShade [NUMERICAL]
# 	6 : Idmn [NUMERICAL]
# 	5 : Contrast [NUMERICAL]
# 	3 : DifferenceAverage [NUMERICAL]
# 	2 : DifferenceEntropy [NUMERICAL]
# 	1 : InverseVariance [NUMERICAL]
# 	1 : Idn [NUMERICAL]
#
# Attribute in nodes with depth <= 2:
# 	240 : Autocorrelation [NUMERICAL]
# 	205 : JointAverage [NUMERICAL]
# 	195 : SumAverage [NUMERICAL]
# 	142 : Imc2 [NUMERICAL]
# 	118 : Imc1 [NUMERICAL]
# 	110 : SumEntropy [NUMERICAL]
# 	87 : JointEnergy [NUMERICAL]
# 	74 : Correlation [NUMERICAL]
# 	58 : MCC [NUMERICAL]
# 	55 : MaximumProbability [NUMERICAL]
# 	55 : JointEntropy [NUMERICAL]
# 	45 : ClusterShade [NUMERICAL]
# 	36 : ClusterTendency [NUMERICAL]
# 	34 : DifferenceVariance [NUMERICAL]
# 	30 : ClusterProminence [NUMERICAL]
# 	25 : Idmn [NUMERICAL]
# 	25 : Id [NUMERICAL]
# 	23 : Contrast [NUMERICAL]
# 	21 : InverseVariance [NUMERICAL]
# 	21 : Idm [NUMERICAL]
# 	20 : DifferenceEntropy [NUMERICAL]
# 	20 : DifferenceAverage [NUMERICAL]
# 	19 : SumSquares [NUMERICAL]
# 	8 : Idn [NUMERICAL]
#
# Attribute in nodes with depth <= 3:
# 	294 : Autocorrelation [NUMERICAL]
# 	259 : JointAverage [NUMERICAL]
# 	244 : SumAverage [NUMERICAL]
# 	179 : Imc2 [NUMERICAL]
# 	151 : Imc1 [NUMERICAL]
# 	141 : SumEntropy [NUMERICAL]
# 	123 : JointEnergy [NUMERICAL]
# 	123 : Correlation [NUMERICAL]
# 	96 : ClusterShade [NUMERICAL]
# 	82 : MaximumProbability [NUMERICAL]
# 	82 : MCC [NUMERICAL]
# 	75 : JointEntropy [NUMERICAL]
# 	57 : DifferenceVariance [NUMERICAL]
# 	54 : Contrast [NUMERICAL]
# 	52 : ClusterTendency [NUMERICAL]
# 	52 : ClusterProminence [NUMERICAL]
# 	50 : Idmn [NUMERICAL]
# 	41 : InverseVariance [NUMERICAL]
# 	39 : Id [NUMERICAL]
# 	38 : Idm [NUMERICAL]
# 	37 : SumSquares [NUMERICAL]
# 	35 : DifferenceAverage [NUMERICAL]
# 	32 : Idn [NUMERICAL]
# 	32 : DifferenceEntropy [NUMERICAL]
#
# Attribute in nodes with depth <= 5:
# 	354 : Autocorrelation [NUMERICAL]
# 	310 : JointAverage [NUMERICAL]
# 	300 : SumAverage [NUMERICAL]
# 	227 : Imc2 [NUMERICAL]
# 	193 : Imc1 [NUMERICAL]
# 	183 : SumEntropy [NUMERICAL]
# 	162 : Correlation [NUMERICAL]
# 	158 : JointEnergy [NUMERICAL]
# 	150 : ClusterShade [NUMERICAL]
# 	128 : MaximumProbability [NUMERICAL]
# 	113 : MCC [NUMERICAL]
# 	99 : JointEntropy [NUMERICAL]
# 	83 : DifferenceVariance [NUMERICAL]
# 	80 : Contrast [NUMERICAL]
# 	79 : ClusterProminence [NUMERICAL]
# 	74 : ClusterTendency [NUMERICAL]
# 	73 : Idmn [NUMERICAL]
# 	66 : DifferenceAverage [NUMERICAL]
# 	65 : InverseVariance [NUMERICAL]
# 	63 : SumSquares [NUMERICAL]
# 	57 : Idm [NUMERICAL]
# 	55 : Id [NUMERICAL]
# 	49 : Idn [NUMERICAL]
# 	45 : DifferenceEntropy [NUMERICAL]
#
# Condition type in nodes:
# 	3334 : HigherCondition
# Condition type in nodes with depth <= 0:
# 	300 : HigherCondition
# Condition type in nodes with depth <= 1:
# 	889 : HigherCondition
# Condition type in nodes with depth <= 2:
# 	1666 : HigherCondition
# Condition type in nodes with depth <= 3:
# 	2368 : HigherCondition
# Condition type in nodes with depth <= 5:
# 	3166 : HigherCondition
# Node format: NOT_SET
#
# Training OOB:
# 	trees: 1, Out-of-bag evaluation: accuracy:0.853956 logloss:5.26397
# 	trees: 13, Out-of-bag evaluation: accuracy:0.931233 logloss:1.62212
# 	trees: 25, Out-of-bag evaluation: accuracy:0.943909 logloss:0.92686
# 	trees: 35, Out-of-bag evaluation: accuracy:0.938114 logloss:0.723922
# 	trees: 45, Out-of-bag evaluation: accuracy:0.938114 logloss:0.528099
# 	trees: 55, Out-of-bag evaluation: accuracy:0.943587 logloss:0.533367
# 	trees: 65, Out-of-bag evaluation: accuracy:0.943587 logloss:0.335322
# 	trees: 76, Out-of-bag evaluation: accuracy:0.943587 logloss:0.142353
# 	trees: 86, Out-of-bag evaluation: accuracy:0.943928 logloss:0.139795
# 	trees: 96, Out-of-bag evaluation: accuracy:0.943928 logloss:0.13679
# 	trees: 107, Out-of-bag evaluation: accuracy:0.944268 logloss:0.133254
# 	trees: 117, Out-of-bag evaluation: accuracy:0.944268 logloss:0.135484
# 	trees: 128, Out-of-bag evaluation: accuracy:0.943928 logloss:0.133862
# 	trees: 138, Out-of-bag evaluation: accuracy:0.943928 logloss:0.132714
# 	trees: 148, Out-of-bag evaluation: accuracy:0.944268 logloss:0.132013
# 	trees: 158, Out-of-bag evaluation: accuracy:0.944268 logloss:0.132523
# 	trees: 168, Out-of-bag evaluation: accuracy:0.938114 logloss:0.129897
# 	trees: 179, Out-of-bag evaluation: accuracy:0.938454 logloss:0.130017
# 	trees: 189, Out-of-bag evaluation: accuracy:0.944268 logloss:0.128956
# 	trees: 199, Out-of-bag evaluation: accuracy:0.944268 logloss:0.130069
# 	trees: 210, Out-of-bag evaluation: accuracy:0.943928 logloss:0.130701
# 	trees: 220, Out-of-bag evaluation: accuracy:0.943928 logloss:0.129218
# 	trees: 230, Out-of-bag evaluation: accuracy:0.943928 logloss:0.12851
# 	trees: 240, Out-of-bag evaluation: accuracy:0.943928 logloss:0.128819
# 	trees: 251, Out-of-bag evaluation: accuracy:0.944268 logloss:0.129952
# 	trees: 261, Out-of-bag evaluation: accuracy:0.944268 logloss:0.130304
# 	trees: 271, Out-of-bag evaluation: accuracy:0.943928 logloss:0.130507
# 	trees: 281, Out-of-bag evaluation: accuracy:0.944268 logloss:0.131355
# 	trees: 291, Out-of-bag evaluation: accuracy:0.944268 logloss:0.131489
# 	trees: 300, Out-of-bag evaluation: accuracy:0.944268 logloss:0.131796

# %%
# Model features
model.make_inspector().features()
# Out:
# ["Autocorrelation" (1; #0),
#  "ClusterProminence" (1; #1),
#  "ClusterShade" (1; #2),
#  "ClusterTendency" (1; #3),
#  "Contrast" (1; #4),
#  "Correlation" (1; #5),
#  "DifferenceAverage" (1; #6),
#  "DifferenceEntropy" (1; #7),
#  "DifferenceVariance" (1; #8),
#  "Id" (1; #9),
#  "Idm" (1; #10),
#  "Idmn" (1; #11),
#  "Idn" (1; #12),
#  "Imc1" (1; #13),
#  "Imc2" (1; #14),
#  "InverseVariance" (1; #15),
#  "JointAverage" (1; #16),
#  "JointEnergy" (1; #17),
#  "JointEntropy" (1; #18),
#  "MCC" (1; #19),
#  "MaximumProbability" (1; #20),
#  "SumAverage" (1; #21),
#  "SumEntropy" (1; #22),
#  "SumSquares" (1; #23)]

# %%
# Feature importance
model.make_inspector().variable_importances()
# Out:
# {'INV_MEAN_MIN_DEPTH': [("Autocorrelation" (1; #0), 0.2664282740862103),
#   ("SumAverage" (1; #21), 0.2657226285977343),
#   ("JointAverage" (1; #16), 0.26036710017698256),
#   ("Imc2" (1; #14), 0.238124515415093),
#   ("Imc1" (1; #13), 0.23023594238650505),
#   ("SumEntropy" (1; #22), 0.22614929554797944),
#   ("JointEnergy" (1; #17), 0.21614634900852564),
#   ("Correlation" (1; #5), 0.21107290530729336),
#   ("MaximumProbability" (1; #20), 0.21065610680949884),
#   ("JointEntropy" (1; #18), 0.20952870424934067),
#   ("MCC" (1; #19), 0.2083120786099371),
#   ("ClusterShade" (1; #2), 0.20524186191327592),
#   ("ClusterProminence" (1; #1), 0.20491307769698727),
#   ("DifferenceVariance" (1; #8), 0.2029663217379415),
#   ("ClusterTendency" (1; #3), 0.20188517885513158),
#   ("Idmn" (1; #11), 0.20073726053869223),
#   ("Idm" (1; #10), 0.1997290204602954),
#   ("Id" (1; #9), 0.19946086739702887),
#   ("SumSquares" (1; #23), 0.1994333689926124),
#   ("Contrast" (1; #4), 0.19927585058810926),
#   ("InverseVariance" (1; #15), 0.19732896052953613),
#   ("DifferenceAverage" (1; #6), 0.19698013693099442),
#   ("Idn" (1; #12), 0.19632055496522127),
#   ("DifferenceEntropy" (1; #7), 0.19626538273673755)],
#  'SUM_SCORE': [("Autocorrelation" (1; #0), 74132.05148457405),
#   ("SumAverage" (1; #21), 66160.76827927282),
#   ("JointAverage" (1; #16), 64457.55529048821),
#   ("Imc2" (1; #14), 21078.721329278946),
#   ("SumEntropy" (1; #22), 17573.89113394639),
#   ("Imc1" (1; #13), 13126.778177801874),
#   ("JointEnergy" (1; #17), 10781.369958685462),
#   ("JointEntropy" (1; #18), 7779.663341538649),
#   ("MaximumProbability" (1; #20), 6355.07776161893),
#   ("Correlation" (1; #5), 5489.92849081963),
#   ("MCC" (1; #19), 4901.292011202668),
#   ("ClusterProminence" (1; #1), 3848.490764530995),
#   ("ClusterShade" (1; #2), 3638.777444877214),
#   ("DifferenceVariance" (1; #8), 2580.743049292459),
#   ("ClusterTendency" (1; #3), 2294.1977179062255),
#   ("Id" (1; #9), 2255.5828125740245),
#   ("Idm" (1; #10), 2024.9803003626728),
#   ("SumSquares" (1; #23), 1900.3710117195337),
#   ("Idmn" (1; #11), 1813.4391088499713),
#   ("Contrast" (1; #4), 1662.2322026994061),
#   ("InverseVariance" (1; #15), 1387.5628289812428),
#   ("DifferenceAverage" (1; #6), 1130.5070322211163),
#   ("DifferenceEntropy" (1; #7), 860.4817748382375),
#   ("Idn" (1; #12), 796.4873628848009)],
#  'NUM_AS_ROOT': [("SumAverage" (1; #21), 61.0),
#   ("Autocorrelation" (1; #0), 58.0),
#   ("JointAverage" (1; #16), 56.0),
#   ("Imc2" (1; #14), 29.0),
#   ("Imc1" (1; #13), 22.0),
#   ("SumEntropy" (1; #22), 22.0),
#   ("JointEnergy" (1; #17), 14.0),
#   ("JointEntropy" (1; #18), 14.0),
#   ("ClusterProminence" (1; #1), 9.0),
#   ("MCC" (1; #19), 5.0),
#   ("ClusterTendency" (1; #3), 3.0),
#   ("SumSquares" (1; #23), 3.0),
#   ("Id" (1; #9), 2.0),
#   ("Correlation" (1; #5), 1.0),
#   ("Idm" (1; #10), 1.0)],
#  'NUM_NODES': [("Autocorrelation" (1; #0), 366.0),
#   ("JointAverage" (1; #16), 321.0),
#   ("SumAverage" (1; #21), 311.0),
#   ("Imc2" (1; #14), 238.0),
#   ("Imc1" (1; #13), 201.0),
#   ("SumEntropy" (1; #22), 189.0),
#   ("Correlation" (1; #5), 170.0),
#   ("JointEnergy" (1; #17), 165.0),
#   ("ClusterShade" (1; #2), 158.0),
#   ("MaximumProbability" (1; #20), 142.0),
#   ("MCC" (1; #19), 118.0),
#   ("JointEntropy" (1; #18), 104.0),
#   ("ClusterProminence" (1; #1), 92.0),
#   ("DifferenceVariance" (1; #8), 90.0),
#   ("Contrast" (1; #4), 89.0),
#   ("ClusterTendency" (1; #3), 75.0),
#   ("Idmn" (1; #11), 75.0),
#   ("DifferenceAverage" (1; #6), 70.0),
#   ("InverseVariance" (1; #15), 69.0),
#   ("Idm" (1; #10), 65.0),
#   ("SumSquares" (1; #23), 65.0),
#   ("Id" (1; #9), 60.0),
#   ("Idn" (1; #12), 54.0),
#   ("DifferenceEntropy" (1; #7), 47.0)]}

# %%
# Model self evaluation
model.make_inspector().evaluation()
# Out:
# Evaluation(num_examples=1554, accuracy=0.9442684254427351, loss=0.13179616322009874, rmse=None, ndcg=None, aucs=None, auuc=None, qini=None)

# %%
logs = model.make_inspector().training_logs()

plt.figure(figsize=(12, 4))
plt.subplot(1, 2, 1)
plt.plot([log.num_trees for log in logs], [log.evaluation.accuracy for log in logs])
plt.xlabel("Number of trees")
plt.ylabel("Accuracy (out-of-bag)")
plt.subplot(1, 2, 2)
plt.plot([log.num_trees for log in logs], [log.evaluation.loss for log in logs])
plt.xlabel("Number of trees")
plt.ylabel("Logloss (out-of-bag)")
plt.show()

# %% [markdown]
# Calculate the score of our hold-out validation dataset

# %%
predictions = model.predict(val_ds)
y_true      = validation_data["label"]

from sklearn.metrics import roc_auc_score
ROC_AUC = roc_auc_score(y_true, predictions)
print("The ROC AUC score is %.5f" % ROC_AUC )
# Out:
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 71ms/step
# The ROC AUC score is 0.99974

# %%
# Compute binary classification metrics with sklearn
import numpy as np
from sklearn.metrics import (
    accuracy_score,
    precision_score,
    recall_score,
    f1_score,
    roc_auc_score,
    average_precision_score,
    confusion_matrix,
    classification_report,
    matthews_corrcoef,
    log_loss,
    brier_score_loss,
)

# Get predictions (probabilities or class labels)
preds = model.predict(test_ds)
# If model outputs probabilities, convert to labels by threshold 0.5
if preds.ndim == 2:
    # For TFDF classification, preds may be class probabilities with shape (N, 2)
    if preds.shape[1] == 2:
        pos_probs = preds[:, 1]
    else:
        # If single-probability column (positive class)
        pos_probs = preds[:, -1]
    y_pred = (pos_probs >= 0.5).astype(int)
else:
    # Already class labels
    y_pred = preds.astype(int)
    pos_probs = None

# Ground truth labels (must be 0/1 integers)
y_true = test_data["label"].astype(int).to_numpy()

# Core metrics
metrics = {}
metrics["accuracy"] = accuracy_score(y_true, y_pred)
metrics["precision"] = precision_score(y_true, y_pred, zero_division=0)
metrics["recall"] = recall_score(y_true, y_pred, zero_division=0)
metrics["f1"] = f1_score(y_true, y_pred, zero_division=0)
metrics["mcc"] = matthews_corrcoef(y_true, y_pred)

# Probabilistic metrics (only if we have probabilities)
if pos_probs is not None:
    metrics["roc_auc"] = roc_auc_score(y_true, pos_probs)
    metrics["pr_auc"] = average_precision_score(y_true, pos_probs)
    metrics["log_loss"] = log_loss(y_true, pos_probs, labels=[0,1])
    metrics["brier_score"] = brier_score_loss(y_true, pos_probs)

# Confusion matrix and detailed report
cm = confusion_matrix(y_true, y_pred, labels=[0,1])
report = classification_report(y_true, y_pred, digits=4)

print("Sklearn binary metrics:")
for k, v in metrics.items():
    print(f"{k}: {v:.4f}")
print("\nConfusion matrix:\n", cm)
print("\nClassification report:\n", report)
# Out:
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 76ms/step
# Sklearn binary metrics:
# accuracy: 0.9887
# precision: 0.9143
# recall: 0.9412
# f1: 0.9275
# mcc: 0.9215
# roc_auc: 0.9985
# pr_auc: 0.9852
# log_loss: 0.0346
# brier_score: 0.0091
#
# Confusion matrix:
#  [[407   3]
#  [  2  32]]
#
# Classification report:
#                precision    recall  f1-score   support
#
#            0     0.9951    0.9927    0.9939       410
#            1     0.9143    0.9412    0.9275        34
#
#     accuracy                         0.9887       444
#    macro avg     0.9547    0.9669    0.9607       444
# weighted avg     0.9889    0.9887    0.9888       444
