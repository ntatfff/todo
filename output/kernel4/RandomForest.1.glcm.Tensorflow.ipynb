# %%
# Import packages and modules
import numpy  as np
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow_decision_forests as tfdf

from sklearn.model_selection import train_test_split
# Out:
# 2026-08-12 05:53:32.988927: I tensorflow/core/util/port.cc:113] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2026-08-12 05:53:33.443095: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2026-08-12 05:53:38.983254: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
# Check the version of TensorFlow Decision Forests
print("Found TensorFlow Decision Forests v" + tfdf.__version__)
# Out:
# Found TensorFlow Decision Forests v1.9.1

# %%
datasetPath = 'dataset/firstorder/kernel5-radius5/dataset.csv'

# %%
# Parameters
datasetPath = "dataset/glcm/kernel4-radius4/1.dataset.csv"

# %%
# train/validation/test = 70/10/20
dataset = pd.read_csv(datasetPath)

train_data, temp_data = train_test_split(dataset, test_size=0.3, random_state=42)
validation_data, test_data = train_test_split(temp_data, test_size=2/3, random_state=42)

# %%
from sklearn.utils.class_weight import compute_class_weight

# tinh class weight tren tap train
classes = np.array([0, 1])
weights = compute_class_weight(class_weight="balanced", classes=classes, y=train_data["label"])
class_weight = {0: weights[0], 1: weights[1]}

# gan sample_weight cho tung dong
train_data["sample_weight"] = train_data["label"].map(class_weight)
validation_data["sample_weight"] = validation_data["label"].map(class_weight)
test_data["sample_weight"] = test_data["label"].map(class_weight)

# Convert the dataset into a TensorFlow dataset.
train_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    train_data, label="label", weight="sample_weight"
)         
val_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    validation_data, label="label", weight="sample_weight"
)
test_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    test_data, label="label", weight="sample_weight"
)
# Out:
# 2026-08-12 05:53:54.424673: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:984] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2026-08-12 05:53:54.426413: W tensorflow/core/common_runtime/gpu/gpu_device.cc:2251] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...

# %%
import keras

# %%
# %%time

# Train a Random Forest model.
model = tfdf.keras.RandomForestModel()

# Add evaluation metrics
model.compile(
    metrics=["accuracy"]
)
model.fit(x=train_ds)

# # Train a Gradient Boosted Trees model.
# model = tfdf.keras.GradientBoostedTreesModel(num_trees=1500)
# model.fit(train_ds)
# Out:
# Use /tmp/tmpta0rjjo1 as temporary training directory
# Reading training dataset...
# Training dataset read in 0:00:02.400833. Found 1336 examples.
# Training model...
# Model trained in 0:00:03.310827
# Compiling model...
# [INFO 26-08-12 05:54:00.3152 UTC kernel.cc:1233] Loading model from path /tmp/tmpta0rjjo1/model/ with prefix 56f5ef726e96490d
# [INFO 26-08-12 05:54:00.3348 UTC decision_forest.cc:734] Model loaded with 300 root(s), 16980 node(s), and 24 input feature(s).
# [INFO 26-08-12 05:54:00.3348 UTC abstract_model.cc:1362] Engine "RandomForestOptPred" built
# [INFO 26-08-12 05:54:00.3348 UTC kernel.cc:1061] Use fast generic engine
# Model compiled.
# CPU times: user 6.88 s, sys: 166 ms, total: 7.04 s
# Wall time: 9.37 s

# %%
# Evaluate the model
evaluate = model.evaluate(val_ds, return_dict=True)
print()

for name, value in evaluate.items():
    print(f"{name}: {value:.4f}")
# Out:
# WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 1/1 [==============================] - ETA: 0s - loss: 0.0000e+00 - accuracy: 0.9843
# 1/1 [==============================] - 3s 3s/step - loss: 0.0000e+00 - accuracy: 0.9843
# loss: 0.0000
# accuracy: 0.9843

# %%
# Model Summary
model.summary()
# Out:
# Model: "random_forest_model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
# =================================================================
# Total params: 1 (1.00 Byte)
# Trainable params: 0 (0.00 Byte)
# Non-trainable params: 1 (1.00 Byte)
# _________________________________________________________________
# Type: "RANDOM_FOREST"
# Task: CLASSIFICATION
# Label: "__LABEL"
#
# Input Features (24):
# 	Autocorrelation
# 	ClusterProminence
# 	ClusterShade
# 	ClusterTendency
# 	Contrast
# 	Correlation
# 	DifferenceAverage
# 	DifferenceEntropy
# 	DifferenceVariance
# 	Id
# 	Idm
# 	Idmn
# 	Idn
# 	Imc1
# 	Imc2
# 	InverseVariance
# 	JointAverage
# 	JointEnergy
# 	JointEntropy
# 	MCC
# 	MaximumProbability
# 	SumAverage
# 	SumEntropy
# 	SumSquares
#
# Trained with weights
#
# Variable Importance: INV_MEAN_MIN_DEPTH:
#     1.    "Autocorrelation"  0.236770 ################
#     2.       "JointAverage"  0.225376 ##############
#     3.         "SumAverage"  0.217899 ############
#     4.                "MCC"  0.178123 #####
#     5. "MaximumProbability"  0.174264 #####
#     6.               "Imc1"  0.169554 ####
#     7.        "Correlation"  0.169186 ####
#     8.    "InverseVariance"  0.164622 ###
#     9.                "Idm"  0.161072 ##
#    10.               "Imc2"  0.157990 ##
#    11.                 "Id"  0.155981 #
#    12.        "JointEnergy"  0.153783 #
#    13.  "DifferenceEntropy"  0.152590 #
#    14.       "ClusterShade"  0.152436 #
#    15.  "DifferenceAverage"  0.150945 #
#    16.                "Idn"  0.149058
#    17.       "JointEntropy"  0.147639
#    18.  "ClusterProminence"  0.147469
#    19. "DifferenceVariance"  0.147352
#    20.         "SumEntropy"  0.147250
#    21.           "Contrast"  0.145929
#    22.    "ClusterTendency"  0.145400
#    23.         "SumSquares"  0.144806
#    24.               "Idmn"  0.144555
#
# Variable Importance: NUM_AS_ROOT:
#     1.    "Autocorrelation" 65.000000 ################
#     2.       "JointAverage" 63.000000 ###############
#     3.         "SumAverage" 56.000000 #############
#     4.                "MCC" 32.000000 #######
#     5. "MaximumProbability" 32.000000 #######
#     6.    "InverseVariance" 15.000000 ###
#     7.        "Correlation" 10.000000 ##
#     8.  "DifferenceEntropy"  8.000000 #
#     9.                "Idn"  5.000000 #
#    10.        "JointEnergy"  4.000000
#    11.  "DifferenceAverage"  3.000000
#    12.           "Contrast"  2.000000
#    13. "DifferenceVariance"  2.000000
#    14.               "Imc1"  2.000000
#    15.               "Idmn"  1.000000
#
# Variable Importance: NUM_NODES:
#     1.    "Autocorrelation" 693.000000 ################
#     2.       "JointAverage" 668.000000 ###############
#     3.         "SumAverage" 614.000000 #############
#     4.               "Imc1" 512.000000 ##########
#     5.        "Correlation" 444.000000 ########
#     6.                "MCC" 442.000000 ########
#     7.               "Imc2" 426.000000 #######
#     8.                "Idm" 405.000000 #######
#     9.       "ClusterShade" 403.000000 #######
#    10. "MaximumProbability" 379.000000 ######
#    11.    "InverseVariance" 364.000000 ######
#    12.                 "Id" 353.000000 #####
#    13.        "JointEnergy" 321.000000 ####
#    14.  "DifferenceEntropy" 250.000000 ##
#    15.       "JointEntropy" 245.000000 ##
#    16.  "ClusterProminence" 240.000000 ##
#    17.         "SumEntropy" 235.000000 ##
#    18.  "DifferenceAverage" 223.000000 #
#    19. "DifferenceVariance" 210.000000 #
#    20.    "ClusterTendency" 195.000000
#    21.                "Idn" 192.000000
#    22.           "Contrast" 185.000000
#    23.         "SumSquares" 175.000000
#    24.               "Idmn" 166.000000
#
# Variable Importance: SUM_SCORE:
#     1.    "Autocorrelation" 67539.626189 ################
#     2.       "JointAverage" 58901.408383 #############
#     3.         "SumAverage" 51291.184640 ############
#     4.                "MCC" 9353.906287 #
#     5.               "Imc1" 8893.864469 #
#     6. "MaximumProbability" 7943.092146 #
#     7.        "Correlation" 7469.034293 #
#     8.                "Idm" 6203.219301 #
#     9.    "InverseVariance" 6182.702551 #
#    10.               "Imc2" 6031.129326 #
#    11.                 "Id" 4200.481522
#    12.        "JointEnergy" 4122.865897
#    13.       "ClusterShade" 3790.841907
#    14.  "DifferenceEntropy" 2633.356643
#    15.  "DifferenceAverage" 2571.322438
#    16.       "JointEntropy" 2327.578087
#    17.         "SumEntropy" 2152.843064
#    18.                "Idn" 2121.041039
#    19.  "ClusterProminence" 1997.283685
#    20. "DifferenceVariance" 1937.457213
#    21.    "ClusterTendency" 1656.168952
#    22.         "SumSquares" 1501.299393
#    23.           "Contrast" 1498.860589
#    24.               "Idmn" 1295.601380
#
#
#
# Winner takes all: true
# Out-of-bag evaluation: accuracy:0.929653 logloss:0.263857
# Number of trees: 300
# Total number of nodes: 16980
#
# Number of nodes by tree:
# Count: 300 Average: 56.6 StdDev: 6.03987
# Min: 41 Max: 75 Ignored: 0
# ----------------------------------------------
# [ 41, 42)  1   0.33%   0.33%
# [ 42, 44)  2   0.67%   1.00%
# [ 44, 46)  7   2.33%   3.33% ##
# [ 46, 48) 11   3.67%   7.00% ##
# [ 48, 49)  0   0.00%   7.00%
# [ 49, 51) 18   6.00%  13.00% ####
# [ 51, 53) 27   9.00%  22.00% ######
# [ 53, 55) 38  12.67%  34.67% ########
# [ 55, 56) 45  15.00%  49.67% ##########
# [ 56, 58) 39  13.00%  62.67% #########
# [ 58, 60) 25   8.33%  71.00% ######
# [ 60, 62) 29   9.67%  80.67% ######
# [ 62, 63)  0   0.00%  80.67%
# [ 63, 65) 19   6.33%  87.00% ####
# [ 65, 67) 21   7.00%  94.00% #####
# [ 67, 69)  7   2.33%  96.33% ##
# [ 69, 70)  6   2.00%  98.33% #
# [ 70, 72)  3   1.00%  99.33% #
# [ 72, 74)  1   0.33%  99.67%
# [ 74, 75]  1   0.33% 100.00%
#
# Depth by leafs:
# Count: 8640 Average: 6.12164 StdDev: 2.13272
# Min: 1 Max: 14 Ignored: 0
# ----------------------------------------------
# [  1,  2)   40   0.46%   0.46%
# [  2,  3)  148   1.71%   2.18% #
# [  3,  4)  571   6.61%   8.78% ####
# [  4,  5) 1322  15.30%  24.09% ########
# [  5,  6) 1589  18.39%  42.48% ##########
# [  6,  7) 1534  17.75%  60.23% ##########
# [  7,  8) 1291  14.94%  75.17% ########
# [  8,  9)  956  11.06%  86.24% ######
# [  9, 10)  572   6.62%  92.86% ####
# [ 10, 11)  328   3.80%  96.66% ##
# [ 11, 12)  204   2.36%  99.02% #
# [ 12, 13)   61   0.71%  99.72%
# [ 13, 14)   20   0.23%  99.95%
# [ 14, 14]    4   0.05% 100.00%
#
# Number of training obs by leaf:
# Count: 8640 Average: 46.3889 StdDev: 116.263
# Min: 5 Max: 909 Ignored: 0
# ----------------------------------------------
# [   5,  50) 7195  83.28%  83.28% ##########
# [  50,  95)  535   6.19%  89.47% #
# [  95, 140)  271   3.14%  92.60%
# [ 140, 186)  104   1.20%  93.81%
# [ 186, 231)   79   0.91%  94.72%
# [ 231, 276)   62   0.72%  95.44%
# [ 276, 321)   38   0.44%  95.88%
# [ 321, 367)   44   0.51%  96.39%
# [ 367, 412)   37   0.43%  96.82%
# [ 412, 457)   56   0.65%  97.47%
# [ 457, 502)   55   0.64%  98.10%
# [ 502, 548)   13   0.15%  98.25%
# [ 548, 593)   26   0.30%  98.55%
# [ 593, 638)   22   0.25%  98.81%
# [ 638, 683)   18   0.21%  99.02%
# [ 683, 729)   14   0.16%  99.18%
# [ 729, 774)   25   0.29%  99.47%
# [ 774, 819)   23   0.27%  99.73%
# [ 819, 864)   16   0.19%  99.92%
# [ 864, 909]    7   0.08% 100.00%
#
# Attribute in nodes:
# 	693 : Autocorrelation [NUMERICAL]
# 	668 : JointAverage [NUMERICAL]
# 	614 : SumAverage [NUMERICAL]
# 	512 : Imc1 [NUMERICAL]
# 	444 : Correlation [NUMERICAL]
# 	442 : MCC [NUMERICAL]
# 	426 : Imc2 [NUMERICAL]
# 	405 : Idm [NUMERICAL]
# 	403 : ClusterShade [NUMERICAL]
# 	379 : MaximumProbability [NUMERICAL]
# 	364 : InverseVariance [NUMERICAL]
# 	353 : Id [NUMERICAL]
# 	321 : JointEnergy [NUMERICAL]
# 	250 : DifferenceEntropy [NUMERICAL]
# 	245 : JointEntropy [NUMERICAL]
# 	240 : ClusterProminence [NUMERICAL]
# 	235 : SumEntropy [NUMERICAL]
# 	223 : DifferenceAverage [NUMERICAL]
# 	210 : DifferenceVariance [NUMERICAL]
# 	195 : ClusterTendency [NUMERICAL]
# 	192 : Idn [NUMERICAL]
# 	185 : Contrast [NUMERICAL]
# 	175 : SumSquares [NUMERICAL]
# 	166 : Idmn [NUMERICAL]
#
# Attribute in nodes with depth <= 0:
# 	65 : Autocorrelation [NUMERICAL]
# 	63 : JointAverage [NUMERICAL]
# 	56 : SumAverage [NUMERICAL]
# 	32 : MaximumProbability [NUMERICAL]
# 	32 : MCC [NUMERICAL]
# 	15 : InverseVariance [NUMERICAL]
# 	10 : Correlation [NUMERICAL]
# 	8 : DifferenceEntropy [NUMERICAL]
# 	5 : Idn [NUMERICAL]
# 	4 : JointEnergy [NUMERICAL]
# 	3 : DifferenceAverage [NUMERICAL]
# 	2 : Imc1 [NUMERICAL]
# 	2 : DifferenceVariance [NUMERICAL]
# 	2 : Contrast [NUMERICAL]
# 	1 : Idmn [NUMERICAL]
#
# Attribute in nodes with depth <= 1:
# 	180 : Autocorrelation [NUMERICAL]
# 	175 : JointAverage [NUMERICAL]
# 	147 : SumAverage [NUMERICAL]
# 	61 : MCC [NUMERICAL]
# 	50 : Correlation [NUMERICAL]
# 	41 : MaximumProbability [NUMERICAL]
# 	37 : Imc1 [NUMERICAL]
# 	32 : InverseVariance [NUMERICAL]
# 	23 : Imc2 [NUMERICAL]
# 	15 : ClusterShade [NUMERICAL]
# 	14 : JointEnergy [NUMERICAL]
# 	12 : DifferenceEntropy [NUMERICAL]
# 	11 : Idm [NUMERICAL]
# 	10 : SumEntropy [NUMERICAL]
# 	10 : Id [NUMERICAL]
# 	10 : DifferenceAverage [NUMERICAL]
# 	9 : Idn [NUMERICAL]
# 	9 : DifferenceVariance [NUMERICAL]
# 	5 : JointEntropy [NUMERICAL]
# 	5 : Contrast [NUMERICAL]
# 	3 : Idmn [NUMERICAL]
# 	1 : ClusterTendency [NUMERICAL]
#
# Attribute in nodes with depth <= 2:
# 	299 : Autocorrelation [NUMERICAL]
# 	285 : JointAverage [NUMERICAL]
# 	255 : SumAverage [NUMERICAL]
# 	114 : Correlation [NUMERICAL]
# 	110 : MCC [NUMERICAL]
# 	94 : Imc1 [NUMERICAL]
# 	77 : InverseVariance [NUMERICAL]
# 	74 : MaximumProbability [NUMERICAL]
# 	69 : Imc2 [NUMERICAL]
# 	63 : Idm [NUMERICAL]
# 	51 : ClusterShade [NUMERICAL]
# 	46 : JointEnergy [NUMERICAL]
# 	43 : Id [NUMERICAL]
# 	38 : DifferenceAverage [NUMERICAL]
# 	37 : DifferenceEntropy [NUMERICAL]
# 	30 : Idn [NUMERICAL]
# 	25 : DifferenceVariance [NUMERICAL]
# 	24 : Contrast [NUMERICAL]
# 	23 : JointEntropy [NUMERICAL]
# 	19 : SumEntropy [NUMERICAL]
# 	19 : Idmn [NUMERICAL]
# 	15 : ClusterProminence [NUMERICAL]
# 	12 : ClusterTendency [NUMERICAL]
# 	10 : SumSquares [NUMERICAL]
#
# Attribute in nodes with depth <= 3:
# 	411 : Autocorrelation [NUMERICAL]
# 	391 : JointAverage [NUMERICAL]
# 	358 : SumAverage [NUMERICAL]
# 	206 : Correlation [NUMERICAL]
# 	203 : Imc1 [NUMERICAL]
# 	177 : MCC [NUMERICAL]
# 	149 : InverseVariance [NUMERICAL]
# 	132 : MaximumProbability [NUMERICAL]
# 	132 : Imc2 [NUMERICAL]
# 	130 : Idm [NUMERICAL]
# 	113 : ClusterShade [NUMERICAL]
# 	111 : JointEnergy [NUMERICAL]
# 	99 : Id [NUMERICAL]
# 	80 : DifferenceEntropy [NUMERICAL]
# 	77 : DifferenceAverage [NUMERICAL]
# 	64 : JointEntropy [NUMERICAL]
# 	63 : Idn [NUMERICAL]
# 	59 : DifferenceVariance [NUMERICAL]
# 	50 : Contrast [NUMERICAL]
# 	45 : ClusterProminence [NUMERICAL]
# 	43 : ClusterTendency [NUMERICAL]
# 	41 : SumEntropy [NUMERICAL]
# 	38 : Idmn [NUMERICAL]
# 	33 : SumSquares [NUMERICAL]
#
# Attribute in nodes with depth <= 5:
# 	570 : Autocorrelation [NUMERICAL]
# 	545 : JointAverage [NUMERICAL]
# 	496 : SumAverage [NUMERICAL]
# 	370 : Imc1 [NUMERICAL]
# 	331 : Correlation [NUMERICAL]
# 	308 : MCC [NUMERICAL]
# 	299 : Imc2 [NUMERICAL]
# 	281 : Idm [NUMERICAL]
# 	267 : ClusterShade [NUMERICAL]
# 	264 : MaximumProbability [NUMERICAL]
# 	259 : InverseVariance [NUMERICAL]
# 	227 : Id [NUMERICAL]
# 	220 : JointEnergy [NUMERICAL]
# 	173 : DifferenceEntropy [NUMERICAL]
# 	158 : JointEntropy [NUMERICAL]
# 	150 : DifferenceAverage [NUMERICAL]
# 	139 : DifferenceVariance [NUMERICAL]
# 	138 : SumEntropy [NUMERICAL]
# 	133 : ClusterProminence [NUMERICAL]
# 	124 : ClusterTendency [NUMERICAL]
# 	121 : Idn [NUMERICAL]
# 	108 : Contrast [NUMERICAL]
# 	105 : SumSquares [NUMERICAL]
# 	102 : Idmn [NUMERICAL]
#
# Condition type in nodes:
# 	8340 : HigherCondition
# Condition type in nodes with depth <= 0:
# 	300 : HigherCondition
# Condition type in nodes with depth <= 1:
# 	860 : HigherCondition
# Condition type in nodes with depth <= 2:
# 	1832 : HigherCondition
# Condition type in nodes with depth <= 3:
# 	3205 : HigherCondition
# Condition type in nodes with depth <= 5:
# 	5888 : HigherCondition
# Node format: NOT_SET
#
# Training OOB:
# 	trees: 1, Out-of-bag evaluation: accuracy:0.917573 logloss:2.97099
# 	trees: 11, Out-of-bag evaluation: accuracy:0.890202 logloss:3.48098
# 	trees: 21, Out-of-bag evaluation: accuracy:0.924795 logloss:0.719835
# 	trees: 31, Out-of-bag evaluation: accuracy:0.922183 logloss:0.603858
# 	trees: 41, Out-of-bag evaluation: accuracy:0.932329 logloss:0.555697
# 	trees: 51, Out-of-bag evaluation: accuracy:0.930555 logloss:0.543241
# 	trees: 61, Out-of-bag evaluation: accuracy:0.932765 logloss:0.52389
# 	trees: 71, Out-of-bag evaluation: accuracy:0.923956 logloss:0.524103
# 	trees: 81, Out-of-bag evaluation: accuracy:0.927474 logloss:0.527364
# 	trees: 91, Out-of-bag evaluation: accuracy:0.927909 logloss:0.527074
# 	trees: 101, Out-of-bag evaluation: accuracy:0.921747 logloss:0.529821
# 	trees: 111, Out-of-bag evaluation: accuracy:0.924828 logloss:0.530947
# 	trees: 121, Out-of-bag evaluation: accuracy:0.921747 logloss:0.446024
# 	trees: 131, Out-of-bag evaluation: accuracy:0.921311 logloss:0.444903
# 	trees: 141, Out-of-bag evaluation: accuracy:0.921747 logloss:0.359092
# 	trees: 151, Out-of-bag evaluation: accuracy:0.922183 logloss:0.359732
# 	trees: 161, Out-of-bag evaluation: accuracy:0.924828 logloss:0.35872
# 	trees: 171, Out-of-bag evaluation: accuracy:0.9257 logloss:0.35949
# 	trees: 181, Out-of-bag evaluation: accuracy:0.923054 logloss:0.358149
# 	trees: 191, Out-of-bag evaluation: accuracy:0.925264 logloss:0.342709
# 	trees: 201, Out-of-bag evaluation: accuracy:0.922183 logloss:0.343716
# 	trees: 211, Out-of-bag evaluation: accuracy:0.9257 logloss:0.344316
# 	trees: 221, Out-of-bag evaluation: accuracy:0.928345 logloss:0.344668
# 	trees: 232, Out-of-bag evaluation: accuracy:0.931427 logloss:0.260955
# 	trees: 242, Out-of-bag evaluation: accuracy:0.928345 logloss:0.261406
# 	trees: 252, Out-of-bag evaluation: accuracy:0.928781 logloss:0.262521
# 	trees: 262, Out-of-bag evaluation: accuracy:0.929217 logloss:0.26332
# 	trees: 272, Out-of-bag evaluation: accuracy:0.929653 logloss:0.264209
# 	trees: 282, Out-of-bag evaluation: accuracy:0.927444 logloss:0.265045
# 	trees: 292, Out-of-bag evaluation: accuracy:0.928781 logloss:0.263826
# 	trees: 300, Out-of-bag evaluation: accuracy:0.929653 logloss:0.263857

# %%
# Model features
model.make_inspector().features()
# Out:
# ["Autocorrelation" (1; #0),
#  "ClusterProminence" (1; #1),
#  "ClusterShade" (1; #2),
#  "ClusterTendency" (1; #3),
#  "Contrast" (1; #4),
#  "Correlation" (1; #5),
#  "DifferenceAverage" (1; #6),
#  "DifferenceEntropy" (1; #7),
#  "DifferenceVariance" (1; #8),
#  "Id" (1; #9),
#  "Idm" (1; #10),
#  "Idmn" (1; #11),
#  "Idn" (1; #12),
#  "Imc1" (1; #13),
#  "Imc2" (1; #14),
#  "InverseVariance" (1; #15),
#  "JointAverage" (1; #16),
#  "JointEnergy" (1; #17),
#  "JointEntropy" (1; #18),
#  "MCC" (1; #19),
#  "MaximumProbability" (1; #20),
#  "SumAverage" (1; #21),
#  "SumEntropy" (1; #22),
#  "SumSquares" (1; #23)]

# %%
# Feature importance
model.make_inspector().variable_importances()
# Out:
# {'INV_MEAN_MIN_DEPTH': [("Autocorrelation" (1; #0), 0.23676979070671436),
#   ("JointAverage" (1; #16), 0.2253755568381221),
#   ("SumAverage" (1; #21), 0.21789861827265902),
#   ("MCC" (1; #19), 0.17812296102033048),
#   ("MaximumProbability" (1; #20), 0.17426446924316893),
#   ("Imc1" (1; #13), 0.16955352353032355),
#   ("Correlation" (1; #5), 0.16918649509100692),
#   ("InverseVariance" (1; #15), 0.16462200770013116),
#   ("Idm" (1; #10), 0.1610721363342568),
#   ("Imc2" (1; #14), 0.15798967553531781),
#   ("Id" (1; #9), 0.1559812338416978),
#   ("JointEnergy" (1; #17), 0.15378343698458208),
#   ("DifferenceEntropy" (1; #7), 0.15259048281912632),
#   ("ClusterShade" (1; #2), 0.15243555935283587),
#   ("DifferenceAverage" (1; #6), 0.15094493683863622),
#   ("Idn" (1; #12), 0.14905801021347756),
#   ("JointEntropy" (1; #18), 0.1476389297999668),
#   ("ClusterProminence" (1; #1), 0.147468928076783),
#   ("DifferenceVariance" (1; #8), 0.14735241500205262),
#   ("SumEntropy" (1; #22), 0.14725022795715534),
#   ("Contrast" (1; #4), 0.14592906451383234),
#   ("ClusterTendency" (1; #3), 0.1453996013870212),
#   ("SumSquares" (1; #23), 0.14480553119610395),
#   ("Idmn" (1; #11), 0.14455500102987562)],
#  'NUM_AS_ROOT': [("Autocorrelation" (1; #0), 65.0),
#   ("JointAverage" (1; #16), 63.0),
#   ("SumAverage" (1; #21), 56.0),
#   ("MCC" (1; #19), 32.0),
#   ("MaximumProbability" (1; #20), 32.0),
#   ("InverseVariance" (1; #15), 15.0),
#   ("Correlation" (1; #5), 10.0),
#   ("DifferenceEntropy" (1; #7), 8.0),
#   ("Idn" (1; #12), 5.0),
#   ("JointEnergy" (1; #17), 4.0),
#   ("DifferenceAverage" (1; #6), 3.0),
#   ("Contrast" (1; #4), 2.0),
#   ("DifferenceVariance" (1; #8), 2.0),
#   ("Imc1" (1; #13), 2.0),
#   ("Idmn" (1; #11), 1.0)],
#  'SUM_SCORE': [("Autocorrelation" (1; #0), 67539.62618861697),
#   ("JointAverage" (1; #16), 58901.408383156384),
#   ("SumAverage" (1; #21), 51291.184640446445),
#   ("MCC" (1; #19), 9353.90628728762),
#   ("Imc1" (1; #13), 8893.864469198395),
#   ("MaximumProbability" (1; #20), 7943.09214592852),
#   ("Correlation" (1; #5), 7469.034292785542),
#   ("Idm" (1; #10), 6203.2193006655425),
#   ("InverseVariance" (1; #15), 6182.702551046301),
#   ("Imc2" (1; #14), 6031.129325945609),
#   ("Id" (1; #9), 4200.481521913333),
#   ("JointEnergy" (1; #17), 4122.865896959206),
#   ("ClusterShade" (1; #2), 3790.8419073654704),
#   ("DifferenceEntropy" (1; #7), 2633.356642610527),
#   ("DifferenceAverage" (1; #6), 2571.3224377577694),
#   ("JointEntropy" (1; #18), 2327.578087180186),
#   ("SumEntropy" (1; #22), 2152.8430638136388),
#   ("Idn" (1; #12), 2121.0410390347033),
#   ("ClusterProminence" (1; #1), 1997.2836847656465),
#   ("DifferenceVariance" (1; #8), 1937.4572132550747),
#   ("ClusterTendency" (1; #3), 1656.168951706388),
#   ("SumSquares" (1; #23), 1501.2993933824232),
#   ("Contrast" (1; #4), 1498.8605887465735),
#   ("Idmn" (1; #11), 1295.6013801532897)],
#  'NUM_NODES': [("Autocorrelation" (1; #0), 693.0),
#   ("JointAverage" (1; #16), 668.0),
#   ("SumAverage" (1; #21), 614.0),
#   ("Imc1" (1; #13), 512.0),
#   ("Correlation" (1; #5), 444.0),
#   ("MCC" (1; #19), 442.0),
#   ("Imc2" (1; #14), 426.0),
#   ("Idm" (1; #10), 405.0),
#   ("ClusterShade" (1; #2), 403.0),
#   ("MaximumProbability" (1; #20), 379.0),
#   ("InverseVariance" (1; #15), 364.0),
#   ("Id" (1; #9), 353.0),
#   ("JointEnergy" (1; #17), 321.0),
#   ("DifferenceEntropy" (1; #7), 250.0),
#   ("JointEntropy" (1; #18), 245.0),
#   ("ClusterProminence" (1; #1), 240.0),
#   ("SumEntropy" (1; #22), 235.0),
#   ("DifferenceAverage" (1; #6), 223.0),
#   ("DifferenceVariance" (1; #8), 210.0),
#   ("ClusterTendency" (1; #3), 195.0),
#   ("Idn" (1; #12), 192.0),
#   ("Contrast" (1; #4), 185.0),
#   ("SumSquares" (1; #23), 175.0),
#   ("Idmn" (1; #11), 166.0)]}

# %%
# Model self evaluation
model.make_inspector().evaluation()
# Out:
# Evaluation(num_examples=1336, accuracy=0.9296531542457428, loss=0.26385719006842473, rmse=None, ndcg=None, aucs=None, auuc=None, qini=None)

# %%
logs = model.make_inspector().training_logs()

plt.figure(figsize=(12, 4))
plt.subplot(1, 2, 1)
plt.plot([log.num_trees for log in logs], [log.evaluation.accuracy for log in logs])
plt.xlabel("Number of trees")
plt.ylabel("Accuracy (out-of-bag)")
plt.subplot(1, 2, 2)
plt.plot([log.num_trees for log in logs], [log.evaluation.loss for log in logs])
plt.xlabel("Number of trees")
plt.ylabel("Logloss (out-of-bag)")
plt.show()

# %% [markdown]
# Calculate the score of our hold-out validation dataset

# %%
predictions = model.predict(val_ds)
y_true      = validation_data["label"]

from sklearn.metrics import roc_auc_score
ROC_AUC = roc_auc_score(y_true, predictions)
print("The ROC AUC score is %.5f" % ROC_AUC )
# Out:
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 74ms/step
# The ROC AUC score is 0.99233

# %%
# Compute binary classification metrics with sklearn
import numpy as np
from sklearn.metrics import (
    accuracy_score,
    precision_score,
    recall_score,
    f1_score,
    roc_auc_score,
    average_precision_score,
    confusion_matrix,
    classification_report,
    matthews_corrcoef,
    log_loss,
    brier_score_loss,
)

# Get predictions (probabilities or class labels)
preds = model.predict(test_ds)
# If model outputs probabilities, convert to labels by threshold 0.5
if preds.ndim == 2:
    # For TFDF classification, preds may be class probabilities with shape (N, 2)
    if preds.shape[1] == 2:
        pos_probs = preds[:, 1]
    else:
        # If single-probability column (positive class)
        pos_probs = preds[:, -1]
    y_pred = (pos_probs >= 0.5).astype(int)
else:
    # Already class labels
    y_pred = preds.astype(int)
    pos_probs = None

# Ground truth labels (must be 0/1 integers)
y_true = test_data["label"].astype(int).to_numpy()

# Core metrics
metrics = {}
metrics["accuracy"] = accuracy_score(y_true, y_pred)
metrics["precision"] = precision_score(y_true, y_pred, zero_division=0)
metrics["recall"] = recall_score(y_true, y_pred, zero_division=0)
metrics["f1"] = f1_score(y_true, y_pred, zero_division=0)
metrics["mcc"] = matthews_corrcoef(y_true, y_pred)

# Probabilistic metrics (only if we have probabilities)
if pos_probs is not None:
    metrics["roc_auc"] = roc_auc_score(y_true, pos_probs)
    metrics["pr_auc"] = average_precision_score(y_true, pos_probs)
    metrics["log_loss"] = log_loss(y_true, pos_probs, labels=[0,1])
    metrics["brier_score"] = brier_score_loss(y_true, pos_probs)

# Confusion matrix and detailed report
cm = confusion_matrix(y_true, y_pred, labels=[0,1])
report = classification_report(y_true, y_pred, digits=4)

print("Sklearn binary metrics:")
for k, v in metrics.items():
    print(f"{k}: {v:.4f}")
print("\nConfusion matrix:\n", cm)
print("\nClassification report:\n", report)
# Out:
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 73ms/step
# Sklearn binary metrics:
# accuracy: 0.9634
# precision: 0.8364
# recall: 0.9020
# f1: 0.8679
# mcc: 0.8475
# roc_auc: 0.9898
# pr_auc: 0.9472
# log_loss: 0.1000
# brier_score: 0.0283
#
# Confusion matrix:
#  [[322   9]
#  [  5  46]]
#
# Classification report:
#                precision    recall  f1-score   support
#
#            0     0.9847    0.9728    0.9787       331
#            1     0.8364    0.9020    0.8679        51
#
#     accuracy                         0.9634       382
#    macro avg     0.9105    0.9374    0.9233       382
# weighted avg     0.9649    0.9634    0.9639       382
