# %%
# Import packages and modules
import numpy  as np
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow_decision_forests as tfdf

from sklearn.model_selection import train_test_split
# Out:
# 2026-08-15 04:59:51.916836: I tensorflow/core/util/port.cc:113] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2026-08-15 04:59:52.282023: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2026-08-15 04:59:57.185686: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
# Check the version of TensorFlow Decision Forests
print("Found TensorFlow Decision Forests v" + tfdf.__version__)
# Out:
# Found TensorFlow Decision Forests v1.9.1

# %%
datasetPath = 'dataset/firstorder/kernel5/dataset.csv'

# %%
# Parameters
datasetPath = "dataset/glrlm/kernel4/1.dataset.csv"

# %%
# train/validation/test = 70/10/20
dataset = pd.read_csv(datasetPath)

train_data, temp_data = train_test_split(dataset, test_size=0.3, random_state=42)
validation_data, test_data = train_test_split(temp_data, test_size=2/3, random_state=42)

# %%
from sklearn.utils.class_weight import compute_class_weight

# tinh class weight tren tap train
classes = np.array([0, 1])
weights = compute_class_weight(class_weight="balanced", classes=classes, y=train_data["label"])
class_weight = {0: weights[0], 1: weights[1]}

# gan sample_weight cho tung dong
train_data["sample_weight"] = train_data["label"].map(class_weight)
validation_data["sample_weight"] = validation_data["label"].map(class_weight)
test_data["sample_weight"] = test_data["label"].map(class_weight)

# Convert the dataset into a TensorFlow dataset.
train_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    train_data, label="label", weight="sample_weight"
)         
val_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    validation_data, label="label", weight="sample_weight"
)
test_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    test_data, label="label", weight="sample_weight"
)
# Out:
# 2026-08-15 05:00:10.261792: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:984] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2026-08-15 05:00:10.263113: W tensorflow/core/common_runtime/gpu/gpu_device.cc:2251] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...

# %%
import keras

# %%
# %%time

# Train a Gradient Boosted Trees model.
model = tfdf.keras.GradientBoostedTreesModel()

# Add evaluation metrics
model.compile(
    metrics=["accuracy"]
)
model.fit(x=train_ds)

# # Train a Gradient Boosted Trees model.
# model = tfdf.keras.GradientBoostedTreesModel(num_trees=1500)
# model.fit(train_ds)
# Out:
# Use /tmp/tmpthzf_aci as temporary training directory
# Reading training dataset...
# [WARNING 26-08-15 05:00:10.4172 UTC gradient_boosted_trees.cc:1840] "goss_alpha" set but "sampling_method" not equal to "GOSS".
# [WARNING 26-08-15 05:00:10.4175 UTC gradient_boosted_trees.cc:1851] "goss_beta" set but "sampling_method" not equal to "GOSS".
# [WARNING 26-08-15 05:00:10.4175 UTC gradient_boosted_trees.cc:1865] "selective_gradient_boosting_ratio" set but "sampling_method" not equal to "SELGB".
# Training dataset read in 0:00:03.240819. Found 1554 examples.
# Training model...
# Model trained in 0:00:00.847842
# Compiling model...
# [INFO 26-08-15 05:00:14.5313 UTC kernel.cc:1233] Loading model from path /tmp/tmpthzf_aci/model/ with prefix 329a02cad29e4e0f
# [INFO 26-08-15 05:00:14.5378 UTC quick_scorer_extended.cc:911] The binary was compiled without AVX2 support, but your CPU supports it. Enable it for faster model inference.
# [INFO 26-08-15 05:00:14.5383 UTC abstract_model.cc:1362] Engine "GradientBoostedTreesQuickScorerExtended" built
# [INFO 26-08-15 05:00:14.5383 UTC kernel.cc:1061] Use fast generic engine
# Model compiled.
# CPU times: user 7.01 s, sys: 1.08 s, total: 8.09 s
# Wall time: 7.41 s

# %%
# Evaluate the model
evaluate = model.evaluate(val_ds, return_dict=True)
print()

for name, value in evaluate.items():
    print(f"{name}: {value:.4f}")
# Out:
# WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 1/1 [==============================] - ETA: 0s - loss: 0.0000e+00 - accuracy: 1.0000
# 1/1 [==============================] - 3s 3s/step - loss: 0.0000e+00 - accuracy: 1.0000
# loss: 0.0000
# accuracy: 1.0000

# %%
# Model Summary
model.summary()
# Out:
# Model: "gradient_boosted_trees_model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
# =================================================================
# Total params: 1 (1.00 Byte)
# Trainable params: 0 (0.00 Byte)
# Non-trainable params: 1 (1.00 Byte)
# _________________________________________________________________
# Type: "GRADIENT_BOOSTED_TREES"
# Task: CLASSIFICATION
# Label: "__LABEL"
#
# Input Features (16):
# 	GrayLevelNonUniformity
# 	GrayLevelNonUniformityNormalized
# 	GrayLevelVariance
# 	HighGrayLevelRunEmphasis
# 	LongRunEmphasis
# 	LongRunHighGrayLevelEmphasis
# 	LongRunLowGrayLevelEmphasis
# 	LowGrayLevelRunEmphasis
# 	RunEntropy
# 	RunLengthNonUniformity
# 	RunLengthNonUniformityNormalized
# 	RunPercentage
# 	RunVariance
# 	ShortRunEmphasis
# 	ShortRunHighGrayLevelEmphasis
# 	ShortRunLowGrayLevelEmphasis
#
# Trained with weights
#
# Variable Importance: INV_MEAN_MIN_DEPTH:
#     1.    "ShortRunHighGrayLevelEmphasis"  0.339961 ################
#     2.                       "RunEntropy"  0.236509 #####
#     3. "GrayLevelNonUniformityNormalized"  0.232101 ####
#     4.     "LongRunHighGrayLevelEmphasis"  0.231875 ####
#     5.      "LongRunLowGrayLevelEmphasis"  0.223903 ###
#     6.     "ShortRunLowGrayLevelEmphasis"  0.214765 ##
#     7.         "HighGrayLevelRunEmphasis"  0.214412 ##
#     8.          "LowGrayLevelRunEmphasis"  0.207235 ##
#     9.           "GrayLevelNonUniformity"  0.206489 ##
#    10.                      "RunVariance"  0.195635
#    11.                "GrayLevelVariance"  0.195157
#    12. "RunLengthNonUniformityNormalized"  0.192930
#    13.                  "LongRunEmphasis"  0.189510
#    14.                    "RunPercentage"  0.188988
#    15.                 "ShortRunEmphasis"  0.188521
#    16.           "RunLengthNonUniformity"  0.187333
#
# Variable Importance: NUM_AS_ROOT:
#     1.    "ShortRunHighGrayLevelEmphasis" 83.000000 ################
#     2.     "LongRunHighGrayLevelEmphasis" 25.000000 ####
#     3.                       "RunEntropy" 19.000000 ###
#     4. "GrayLevelNonUniformityNormalized" 14.000000 ##
#     5.         "HighGrayLevelRunEmphasis" 14.000000 ##
#     6.      "LongRunLowGrayLevelEmphasis"  9.000000 #
#     7.          "LowGrayLevelRunEmphasis"  6.000000
#     8.           "GrayLevelNonUniformity"  2.000000
#     9.                      "RunVariance"  1.000000
#    10.     "ShortRunLowGrayLevelEmphasis"  1.000000
#
# Variable Importance: NUM_NODES:
#     1.    "ShortRunHighGrayLevelEmphasis" 317.000000 ################
#     2. "GrayLevelNonUniformityNormalized" 315.000000 ###############
#     3.     "LongRunHighGrayLevelEmphasis" 281.000000 ##############
#     4.                       "RunEntropy" 276.000000 #############
#     5.      "LongRunLowGrayLevelEmphasis" 269.000000 #############
#     6.     "ShortRunLowGrayLevelEmphasis" 226.000000 ##########
#     7.           "GrayLevelNonUniformity" 221.000000 ##########
#     8.          "LowGrayLevelRunEmphasis" 206.000000 #########
#     9.         "HighGrayLevelRunEmphasis" 197.000000 #########
#    10.                "GrayLevelVariance" 158.000000 #######
#    11.                      "RunVariance" 112.000000 ####
#    12. "RunLengthNonUniformityNormalized" 64.000000 #
#    13.                  "LongRunEmphasis" 48.000000 #
#    14.                 "ShortRunEmphasis" 46.000000
#    15.                    "RunPercentage" 40.000000
#    16.           "RunLengthNonUniformity" 29.000000
#
# Variable Importance: SUM_SCORE:
#     1.    "ShortRunHighGrayLevelEmphasis" 1564.929480 ################
#     2.                       "RunEntropy" 133.082811 #
#     3. "GrayLevelNonUniformityNormalized" 50.217821
#     4.      "LongRunLowGrayLevelEmphasis" 31.576024
#     5.          "LowGrayLevelRunEmphasis" 23.906328
#     6.     "ShortRunLowGrayLevelEmphasis" 21.065533
#     7.           "GrayLevelNonUniformity" 17.679141
#     8.                "GrayLevelVariance" 12.236421
#     9.     "LongRunHighGrayLevelEmphasis" 12.122647
#    10.         "HighGrayLevelRunEmphasis"  2.897506
#    11.                      "RunVariance"  2.175059
#    12.                 "ShortRunEmphasis"  1.818205
#    13. "RunLengthNonUniformityNormalized"  0.963137
#    14.                  "LongRunEmphasis"  0.498079
#    15.           "RunLengthNonUniformity"  0.259765
#    16.                    "RunPercentage"  0.214118
#
#
#
# Loss: BINOMIAL_LOG_LIKELIHOOD
# Validation loss value: 0.00216498
# Number of trees per iteration: 1
# Node format: NOT_SET
# Number of trees: 174
# Total number of nodes: 5784
#
# Number of nodes by tree:
# Count: 174 Average: 33.2414 StdDev: 7.6781
# Min: 19 Max: 47 Ignored: 0
# ----------------------------------------------
# [ 19, 20)  2   1.15%   1.15% #
# [ 20, 21)  0   0.00%   1.15%
# [ 21, 23) 13   7.47%   8.62% ######
# [ 23, 24) 15   8.62%  17.24% #######
# [ 24, 26)  8   4.60%  21.84% ####
# [ 26, 27)  0   0.00%  21.84%
# [ 27, 29) 10   5.75%  27.59% #####
# [ 29, 30) 11   6.32%  33.91% #####
# [ 30, 32) 21  12.07%  45.98% ##########
# [ 32, 33)  0   0.00%  45.98%
# [ 33, 34) 18  10.34%  56.32% #########
# [ 34, 36) 10   5.75%  62.07% #####
# [ 36, 37)  0   0.00%  62.07%
# [ 37, 39)  6   3.45%  65.52% ###
# [ 39, 40) 16   9.20%  74.71% ########
# [ 40, 42) 14   8.05%  82.76% #######
# [ 42, 43)  0   0.00%  82.76%
# [ 43, 45) 15   8.62%  91.38% #######
# [ 45, 46) 13   7.47%  98.85% ######
# [ 46, 47]  2   1.15% 100.00% #
#
# Depth by leafs:
# Count: 2979 Average: 4.43874 StdDev: 0.875532
# Min: 2 Max: 5 Ignored: 0
# ----------------------------------------------
# [ 2, 3)  142   4.77%   4.77% #
# [ 3, 4)  349  11.72%  16.48% ##
# [ 4, 5)  548  18.40%  34.88% ###
# [ 5, 5] 1940  65.12% 100.00% ##########
#
# Number of training obs by leaf:
# Count: 2979 Average: 83.2326 StdDev: 267.801
# Min: 5 Max: 1338 Ignored: 0
# ----------------------------------------------
# [    5,   71) 2698  90.57%  90.57% ##########
# [   71,  138)   67   2.25%  92.82%
# [  138,  205)   16   0.54%  93.35%
# [  205,  271)   13   0.44%  93.79%
# [  271,  338)    5   0.17%  93.96%
# [  338,  405)    1   0.03%  93.99%
# [  405,  471)    1   0.03%  94.02%
# [  471,  538)    5   0.17%  94.19%
# [  538,  605)    0   0.00%  94.19%
# [  605,  672)    5   0.17%  94.36%
# [  672,  738)    0   0.00%  94.36%
# [  738,  805)    2   0.07%  94.43%
# [  805,  872)    4   0.13%  94.56%
# [  872,  938)   16   0.54%  95.10%
# [  938, 1005)    4   0.13%  95.23%
# [ 1005, 1072)    4   0.13%  95.37%
# [ 1072, 1138)    6   0.20%  95.57%
# [ 1138, 1205)   85   2.85%  98.42%
# [ 1205, 1272)   30   1.01%  99.43%
# [ 1272, 1338]   17   0.57% 100.00%
#
# Attribute in nodes:
# 	317 : ShortRunHighGrayLevelEmphasis [NUMERICAL]
# 	315 : GrayLevelNonUniformityNormalized [NUMERICAL]
# 	281 : LongRunHighGrayLevelEmphasis [NUMERICAL]
# 	276 : RunEntropy [NUMERICAL]
# 	269 : LongRunLowGrayLevelEmphasis [NUMERICAL]
# 	226 : ShortRunLowGrayLevelEmphasis [NUMERICAL]
# 	221 : GrayLevelNonUniformity [NUMERICAL]
# 	206 : LowGrayLevelRunEmphasis [NUMERICAL]
# 	197 : HighGrayLevelRunEmphasis [NUMERICAL]
# 	158 : GrayLevelVariance [NUMERICAL]
# 	112 : RunVariance [NUMERICAL]
# 	64 : RunLengthNonUniformityNormalized [NUMERICAL]
# 	48 : LongRunEmphasis [NUMERICAL]
# 	46 : ShortRunEmphasis [NUMERICAL]
# 	40 : RunPercentage [NUMERICAL]
# 	29 : RunLengthNonUniformity [NUMERICAL]
#
# Attribute in nodes with depth <= 0:
# 	83 : ShortRunHighGrayLevelEmphasis [NUMERICAL]
# 	25 : LongRunHighGrayLevelEmphasis [NUMERICAL]
# 	19 : RunEntropy [NUMERICAL]
# 	14 : HighGrayLevelRunEmphasis [NUMERICAL]
# 	14 : GrayLevelNonUniformityNormalized [NUMERICAL]
# 	9 : LongRunLowGrayLevelEmphasis [NUMERICAL]
# 	6 : LowGrayLevelRunEmphasis [NUMERICAL]
# 	2 : GrayLevelNonUniformity [NUMERICAL]
# 	1 : ShortRunLowGrayLevelEmphasis [NUMERICAL]
# 	1 : RunVariance [NUMERICAL]
#
# Attribute in nodes with depth <= 1:
# 	134 : ShortRunHighGrayLevelEmphasis [NUMERICAL]
# 	68 : RunEntropy [NUMERICAL]
# 	61 : GrayLevelNonUniformityNormalized [NUMERICAL]
# 	55 : LongRunHighGrayLevelEmphasis [NUMERICAL]
# 	49 : LongRunLowGrayLevelEmphasis [NUMERICAL]
# 	47 : ShortRunLowGrayLevelEmphasis [NUMERICAL]
# 	34 : LowGrayLevelRunEmphasis [NUMERICAL]
# 	29 : HighGrayLevelRunEmphasis [NUMERICAL]
# 	17 : GrayLevelNonUniformity [NUMERICAL]
# 	8 : RunLengthNonUniformityNormalized [NUMERICAL]
# 	7 : LongRunEmphasis [NUMERICAL]
# 	6 : GrayLevelVariance [NUMERICAL]
# 	5 : RunVariance [NUMERICAL]
# 	2 : RunLengthNonUniformity [NUMERICAL]
#
# Attribute in nodes with depth <= 2:
# 	183 : ShortRunHighGrayLevelEmphasis [NUMERICAL]
# 	124 : RunEntropy [NUMERICAL]
# 	120 : LongRunHighGrayLevelEmphasis [NUMERICAL]
# 	116 : GrayLevelNonUniformityNormalized [NUMERICAL]
# 	110 : LongRunLowGrayLevelEmphasis [NUMERICAL]
# 	83 : ShortRunLowGrayLevelEmphasis [NUMERICAL]
# 	69 : HighGrayLevelRunEmphasis [NUMERICAL]
# 	67 : GrayLevelNonUniformity [NUMERICAL]
# 	61 : LowGrayLevelRunEmphasis [NUMERICAL]
# 	38 : GrayLevelVariance [NUMERICAL]
# 	35 : RunVariance [NUMERICAL]
# 	25 : RunLengthNonUniformityNormalized [NUMERICAL]
# 	16 : RunPercentage [NUMERICAL]
# 	12 : ShortRunEmphasis [NUMERICAL]
# 	9 : LongRunEmphasis [NUMERICAL]
# 	8 : RunLengthNonUniformity [NUMERICAL]
#
# Attribute in nodes with depth <= 3:
# 	237 : ShortRunHighGrayLevelEmphasis [NUMERICAL]
# 	216 : GrayLevelNonUniformityNormalized [NUMERICAL]
# 	197 : LongRunHighGrayLevelEmphasis [NUMERICAL]
# 	185 : RunEntropy [NUMERICAL]
# 	170 : LongRunLowGrayLevelEmphasis [NUMERICAL]
# 	147 : ShortRunLowGrayLevelEmphasis [NUMERICAL]
# 	141 : GrayLevelNonUniformity [NUMERICAL]
# 	121 : LowGrayLevelRunEmphasis [NUMERICAL]
# 	116 : HighGrayLevelRunEmphasis [NUMERICAL]
# 	96 : GrayLevelVariance [NUMERICAL]
# 	71 : RunVariance [NUMERICAL]
# 	41 : RunLengthNonUniformityNormalized [NUMERICAL]
# 	34 : LongRunEmphasis [NUMERICAL]
# 	26 : RunPercentage [NUMERICAL]
# 	25 : ShortRunEmphasis [NUMERICAL]
# 	12 : RunLengthNonUniformity [NUMERICAL]
#
# Attribute in nodes with depth <= 5:
# 	317 : ShortRunHighGrayLevelEmphasis [NUMERICAL]
# 	315 : GrayLevelNonUniformityNormalized [NUMERICAL]
# 	281 : LongRunHighGrayLevelEmphasis [NUMERICAL]
# 	276 : RunEntropy [NUMERICAL]
# 	269 : LongRunLowGrayLevelEmphasis [NUMERICAL]
# 	226 : ShortRunLowGrayLevelEmphasis [NUMERICAL]
# 	221 : GrayLevelNonUniformity [NUMERICAL]
# 	206 : LowGrayLevelRunEmphasis [NUMERICAL]
# 	197 : HighGrayLevelRunEmphasis [NUMERICAL]
# 	158 : GrayLevelVariance [NUMERICAL]
# 	112 : RunVariance [NUMERICAL]
# 	64 : RunLengthNonUniformityNormalized [NUMERICAL]
# 	48 : LongRunEmphasis [NUMERICAL]
# 	46 : ShortRunEmphasis [NUMERICAL]
# 	40 : RunPercentage [NUMERICAL]
# 	29 : RunLengthNonUniformity [NUMERICAL]
#
# Condition type in nodes:
# 	2805 : HigherCondition
# Condition type in nodes with depth <= 0:
# 	174 : HigherCondition
# Condition type in nodes with depth <= 1:
# 	522 : HigherCondition
# Condition type in nodes with depth <= 2:
# 	1076 : HigherCondition
# Condition type in nodes with depth <= 3:
# 	1835 : HigherCondition
# Condition type in nodes with depth <= 5:
# 	2805 : HigherCondition
#
# Training logs:
# Number of iteration to final model: 174
# 	Iter:1 train-loss:1.201728 valid-loss:1.204070  train-accuracy:0.991256 valid-accuracy:0.989273
# 	Iter:2 train-loss:1.050791 valid-loss:1.051564  train-accuracy:0.991636 valid-accuracy:0.989273
# 	Iter:3 train-loss:0.924967 valid-loss:0.923391  train-accuracy:0.992396 valid-accuracy:0.992849
# 	Iter:4 train-loss:0.818420 valid-loss:0.816098  train-accuracy:0.991636 valid-accuracy:0.989273
# 	Iter:5 train-loss:0.727339 valid-loss:0.722625  train-accuracy:0.991636 valid-accuracy:0.989273
# 	Iter:6 train-loss:0.648144 valid-loss:0.640900  train-accuracy:0.993917 valid-accuracy:0.992849
# 	Iter:16 train-loss:0.234414 valid-loss:0.220282  train-accuracy:0.994677 valid-accuracy:0.996424
# 	Iter:26 train-loss:0.091918 valid-loss:0.088018  train-accuracy:0.997719 valid-accuracy:1.000000
# 	Iter:36 train-loss:0.038971 valid-loss:0.043554  train-accuracy:0.998479 valid-accuracy:1.000000
# 	Iter:46 train-loss:0.018866 valid-loss:0.021326  train-accuracy:0.999240 valid-accuracy:1.000000
# 	Iter:56 train-loss:0.010121 valid-loss:0.012682  train-accuracy:0.999620 valid-accuracy:1.000000
# 	Iter:66 train-loss:0.005738 valid-loss:0.008855  train-accuracy:0.999620 valid-accuracy:1.000000
# 	Iter:76 train-loss:0.003205 valid-loss:0.006795  train-accuracy:1.000000 valid-accuracy:1.000000
# 	Iter:86 train-loss:0.001807 valid-loss:0.006692  train-accuracy:1.000000 valid-accuracy:1.000000
# 	Iter:96 train-loss:0.001056 valid-loss:0.006178  train-accuracy:1.000000 valid-accuracy:1.000000
# 	Iter:106 train-loss:0.000673 valid-loss:0.005321  train-accuracy:1.000000 valid-accuracy:1.000000
# 	Iter:116 train-loss:0.000422 valid-loss:0.005216  train-accuracy:1.000000 valid-accuracy:1.000000
# 	Iter:126 train-loss:0.000274 valid-loss:0.006110  train-accuracy:1.000000 valid-accuracy:1.000000
# 	Iter:136 train-loss:0.000173 valid-loss:0.005980  train-accuracy:1.000000 valid-accuracy:1.000000
# 	Iter:146 train-loss:0.000116 valid-loss:0.004324  train-accuracy:1.000000 valid-accuracy:1.000000
# 	Iter:156 train-loss:0.000077 valid-loss:0.003447  train-accuracy:1.000000 valid-accuracy:1.000000
# 	Iter:166 train-loss:0.000053 valid-loss:0.003298  train-accuracy:1.000000 valid-accuracy:1.000000
# 	Iter:176 train-loss:0.000035 valid-loss:0.002444  train-accuracy:1.000000 valid-accuracy:1.000000
# 	Iter:186 train-loss:0.000026 valid-loss:0.002456  train-accuracy:1.000000 valid-accuracy:1.000000
# 	Iter:196 train-loss:0.000021 valid-loss:0.002508  train-accuracy:1.000000 valid-accuracy:1.000000

# %%
# Model features
model.make_inspector().features()
# Out:
# ["GrayLevelNonUniformity" (1; #0),
#  "GrayLevelNonUniformityNormalized" (1; #1),
#  "GrayLevelVariance" (1; #2),
#  "HighGrayLevelRunEmphasis" (1; #3),
#  "LongRunEmphasis" (1; #4),
#  "LongRunHighGrayLevelEmphasis" (1; #5),
#  "LongRunLowGrayLevelEmphasis" (1; #6),
#  "LowGrayLevelRunEmphasis" (1; #7),
#  "RunEntropy" (1; #8),
#  "RunLengthNonUniformity" (1; #9),
#  "RunLengthNonUniformityNormalized" (1; #10),
#  "RunPercentage" (1; #11),
#  "RunVariance" (1; #12),
#  "ShortRunEmphasis" (1; #13),
#  "ShortRunHighGrayLevelEmphasis" (1; #14),
#  "ShortRunLowGrayLevelEmphasis" (1; #15)]

# %%
# Feature importance
model.make_inspector().variable_importances()
# Out:
# {'INV_MEAN_MIN_DEPTH': [("ShortRunHighGrayLevelEmphasis" (1; #14),
#    0.3399611360812167),
#   ("RunEntropy" (1; #8), 0.2365090350188739),
#   ("GrayLevelNonUniformityNormalized" (1; #1), 0.23210119499875304),
#   ("LongRunHighGrayLevelEmphasis" (1; #5), 0.23187461512158453),
#   ("LongRunLowGrayLevelEmphasis" (1; #6), 0.2239031878179903),
#   ("ShortRunLowGrayLevelEmphasis" (1; #15), 0.21476540152464596),
#   ("HighGrayLevelRunEmphasis" (1; #3), 0.2144121596957567),
#   ("LowGrayLevelRunEmphasis" (1; #7), 0.20723503887287406),
#   ("GrayLevelNonUniformity" (1; #0), 0.20648863066118117),
#   ("RunVariance" (1; #12), 0.19563475027819338),
#   ("GrayLevelVariance" (1; #2), 0.19515743089766627),
#   ("RunLengthNonUniformityNormalized" (1; #10), 0.1929295003647561),
#   ("LongRunEmphasis" (1; #4), 0.18950999620698397),
#   ("RunPercentage" (1; #11), 0.18898768305479344),
#   ("ShortRunEmphasis" (1; #13), 0.1885212555661493),
#   ("RunLengthNonUniformity" (1; #9), 0.1873331486020978)],
#  'NUM_AS_ROOT': [("ShortRunHighGrayLevelEmphasis" (1; #14), 83.0),
#   ("LongRunHighGrayLevelEmphasis" (1; #5), 25.0),
#   ("RunEntropy" (1; #8), 19.0),
#   ("GrayLevelNonUniformityNormalized" (1; #1), 14.0),
#   ("HighGrayLevelRunEmphasis" (1; #3), 14.0),
#   ("LongRunLowGrayLevelEmphasis" (1; #6), 9.0),
#   ("LowGrayLevelRunEmphasis" (1; #7), 6.0),
#   ("GrayLevelNonUniformity" (1; #0), 2.0),
#   ("RunVariance" (1; #12), 1.0),
#   ("ShortRunLowGrayLevelEmphasis" (1; #15), 1.0)],
#  'SUM_SCORE': [("ShortRunHighGrayLevelEmphasis" (1; #14), 1564.929479523574),
#   ("RunEntropy" (1; #8), 133.08281135658632),
#   ("GrayLevelNonUniformityNormalized" (1; #1), 50.21782079178259),
#   ("LongRunLowGrayLevelEmphasis" (1; #6), 31.576024232809335),
#   ("LowGrayLevelRunEmphasis" (1; #7), 23.90632813112935),
#   ("ShortRunLowGrayLevelEmphasis" (1; #15), 21.065533441105963),
#   ("GrayLevelNonUniformity" (1; #0), 17.679140960351585),
#   ("GrayLevelVariance" (1; #2), 12.236421293693493),
#   ("LongRunHighGrayLevelEmphasis" (1; #5), 12.122646741092387),
#   ("HighGrayLevelRunEmphasis" (1; #3), 2.8975056118083207),
#   ("RunVariance" (1; #12), 2.1750591346657706),
#   ("ShortRunEmphasis" (1; #13), 1.818204784382923),
#   ("RunLengthNonUniformityNormalized" (1; #10), 0.963136881516121),
#   ("LongRunEmphasis" (1; #4), 0.49807908344181756),
#   ("RunLengthNonUniformity" (1; #9), 0.2597645444366505),
#   ("RunPercentage" (1; #11), 0.2141177817913214)],
#  'NUM_NODES': [("ShortRunHighGrayLevelEmphasis" (1; #14), 317.0),
#   ("GrayLevelNonUniformityNormalized" (1; #1), 315.0),
#   ("LongRunHighGrayLevelEmphasis" (1; #5), 281.0),
#   ("RunEntropy" (1; #8), 276.0),
#   ("LongRunLowGrayLevelEmphasis" (1; #6), 269.0),
#   ("ShortRunLowGrayLevelEmphasis" (1; #15), 226.0),
#   ("GrayLevelNonUniformity" (1; #0), 221.0),
#   ("LowGrayLevelRunEmphasis" (1; #7), 206.0),
#   ("HighGrayLevelRunEmphasis" (1; #3), 197.0),
#   ("GrayLevelVariance" (1; #2), 158.0),
#   ("RunVariance" (1; #12), 112.0),
#   ("RunLengthNonUniformityNormalized" (1; #10), 64.0),
#   ("LongRunEmphasis" (1; #4), 48.0),
#   ("ShortRunEmphasis" (1; #13), 46.0),
#   ("RunPercentage" (1; #11), 40.0),
#   ("RunLengthNonUniformity" (1; #9), 29.0)]}

# %%
# Model self evaluation
model.make_inspector().evaluation()
# Out:
# Evaluation(num_examples=None, accuracy=1.0, loss=0.0021649752743542194, rmse=None, ndcg=None, aucs=None, auuc=None, qini=None)

# %%
logs = model.make_inspector().training_logs()

plt.figure(figsize=(12, 4))
plt.subplot(1, 2, 1)
plt.plot([log.num_trees for log in logs], [log.evaluation.accuracy for log in logs])
plt.xlabel("Number of trees")
plt.ylabel("Accuracy (out-of-bag)")
plt.subplot(1, 2, 2)
plt.plot([log.num_trees for log in logs], [log.evaluation.loss for log in logs])
plt.xlabel("Number of trees")
plt.ylabel("Logloss (out-of-bag)")
plt.show()

# %% [markdown]
# Calculate the score of our hold-out validation dataset

# %%
predictions = model.predict(val_ds)
y_true      = validation_data["label"]

from sklearn.metrics import roc_auc_score
ROC_AUC = roc_auc_score(y_true, predictions)
print("The ROC AUC score is %.5f" % ROC_AUC )
# Out:
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 61ms/step
# The ROC AUC score is 1.00000

# %%
# Compute binary classification metrics with sklearn
import numpy as np
from sklearn.metrics import (
    accuracy_score,
    precision_score,
    recall_score,
    f1_score,
    roc_auc_score,
    average_precision_score,
    confusion_matrix,
    classification_report,
    matthews_corrcoef,
    log_loss,
    brier_score_loss,
)

# Get predictions (probabilities or class labels)
preds = model.predict(test_ds)
# If model outputs probabilities, convert to labels by threshold 0.5
if preds.ndim == 2:
    # For TFDF classification, preds may be class probabilities with shape (N, 2)
    if preds.shape[1] == 2:
        pos_probs = preds[:, 1]
    else:
        # If single-probability column (positive class)
        pos_probs = preds[:, -1]
    y_pred = (pos_probs >= 0.5).astype(int)
else:
    # Already class labels
    y_pred = preds.astype(int)
    pos_probs = None

# Ground truth labels (must be 0/1 integers)
y_true = test_data["label"].astype(int).to_numpy()

# Core metrics
metrics = {}
metrics["accuracy"] = accuracy_score(y_true, y_pred)
metrics["precision"] = precision_score(y_true, y_pred, zero_division=0)
metrics["recall"] = recall_score(y_true, y_pred, zero_division=0)
metrics["f1"] = f1_score(y_true, y_pred, zero_division=0)
metrics["mcc"] = matthews_corrcoef(y_true, y_pred)

# Probabilistic metrics (only if we have probabilities)
if pos_probs is not None:
    metrics["roc_auc"] = roc_auc_score(y_true, pos_probs)
    metrics["pr_auc"] = average_precision_score(y_true, pos_probs)
    metrics["log_loss"] = log_loss(y_true, pos_probs, labels=[0,1])
    metrics["brier_score"] = brier_score_loss(y_true, pos_probs)

# Confusion matrix and detailed report
cm = confusion_matrix(y_true, y_pred, labels=[0,1])
report = classification_report(y_true, y_pred, digits=4)

print("Sklearn binary metrics:")
for k, v in metrics.items():
    print(f"{k}: {v:.4f}")
print("\nConfusion matrix:\n", cm)
print("\nClassification report:\n", report)
# Out:
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 65ms/step
# Sklearn binary metrics:
# accuracy: 0.9932
# precision: 0.9333
# recall: 0.9655
# f1: 0.9492
# mcc: 0.9457
# roc_auc: 0.9995
# pr_auc: 0.9931
# log_loss: 0.0292
# brier_score: 0.0065
#
# Confusion matrix:
#  [[413   2]
#  [  1  28]]
#
# Classification report:
#                precision    recall  f1-score   support
#
#            0     0.9976    0.9952    0.9964       415
#            1     0.9333    0.9655    0.9492        29
#
#     accuracy                         0.9932       444
#    macro avg     0.9655    0.9803    0.9728       444
# weighted avg     0.9934    0.9932    0.9933       444
