# %%
# Import packages and modules
import numpy  as np
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow_decision_forests as tfdf

from sklearn.model_selection import train_test_split
# Out:
# 2026-08-10 17:12:09.026874: I tensorflow/core/util/port.cc:113] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2026-08-10 17:12:09.489795: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2026-08-10 17:12:14.548763: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
# Check the version of TensorFlow Decision Forests
print("Found TensorFlow Decision Forests v" + tfdf.__version__)
# Out:
# Found TensorFlow Decision Forests v1.9.1

# %%
datasetPath = 'dataset/firstorder/kernel5-radius5/dataset.csv'

# %%
# Parameters
datasetPath = "dataset/glrlm/kernel4-radius4/dataset.1p.csv"

# %%
# train/validation/test = 70/10/20
dataset = pd.read_csv(datasetPath)

train_data, temp_data = train_test_split(dataset, test_size=0.3, random_state=42)
validation_data, test_data = train_test_split(temp_data, test_size=2/3, random_state=42)

# %%
from sklearn.utils.class_weight import compute_class_weight

# tinh class weight tren tap train
classes = np.array([0, 1])
weights = compute_class_weight(class_weight="balanced", classes=classes, y=train_data["label"])
class_weight = {0: weights[0], 1: weights[1]}

# gan sample_weight cho tung dong
train_data["sample_weight"] = train_data["label"].map(class_weight)
validation_data["sample_weight"] = validation_data["label"].map(class_weight)
test_data["sample_weight"] = test_data["label"].map(class_weight)

# Convert the dataset into a TensorFlow dataset.
train_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    train_data, label="label", weight="sample_weight"
)         
val_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    validation_data, label="label", weight="sample_weight"
)
test_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    test_data, label="label", weight="sample_weight"
)
# Out:
# 2026-08-10 17:12:29.693266: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:984] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2026-08-10 17:12:29.694791: W tensorflow/core/common_runtime/gpu/gpu_device.cc:2251] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...

# %%
import keras

# %%
# %%time

# Train a Gradient Boosted Trees model.
model = tfdf.keras.GradientBoostedTreesModel()

# Add evaluation metrics
model.compile(
    metrics=["accuracy"]
)
model.fit(x=train_ds)

# # Train a Gradient Boosted Trees model.
# model = tfdf.keras.GradientBoostedTreesModel(num_trees=1500)
# model.fit(train_ds)
# Out:
# Use /tmp/tmp95latz4b as temporary training directory
# Reading training dataset...
# [WARNING 26-08-10 17:12:29.8635 UTC gradient_boosted_trees.cc:1840] "goss_alpha" set but "sampling_method" not equal to "GOSS".
# [WARNING 26-08-10 17:12:29.8637 UTC gradient_boosted_trees.cc:1851] "goss_beta" set but "sampling_method" not equal to "GOSS".
# [WARNING 26-08-10 17:12:29.8637 UTC gradient_boosted_trees.cc:1865] "selective_gradient_boosting_ratio" set but "sampling_method" not equal to "SELGB".
# Training dataset read in 0:00:02.525479. Found 1542 examples.
# Training model...
# Model trained in 0:00:01.758137
# Compiling model...
# [INFO 26-08-10 17:12:34.1613 UTC kernel.cc:1233] Loading model from path /tmp/tmp95latz4b/model/ with prefix cf03b4479ee64232
# [INFO 26-08-10 17:12:34.1729 UTC quick_scorer_extended.cc:911] The binary was compiled without AVX2 support, but your CPU supports it. Enable it for faster model inference.
# [INFO 26-08-10 17:12:34.1737 UTC abstract_model.cc:1362] Engine "GradientBoostedTreesQuickScorerExtended" built
# [INFO 26-08-10 17:12:34.1738 UTC kernel.cc:1061] Use fast generic engine
# Model compiled.
# CPU times: user 8.77 s, sys: 2.12 s, total: 10.9 s
# Wall time: 7.32 s

# %%
# Evaluate the model
evaluate = model.evaluate(val_ds, return_dict=True)
print()

for name, value in evaluate.items():
    print(f"{name}: {value:.4f}")
# Out:
# WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 1/1 [==============================] - ETA: 0s - loss: 0.0000e+00 - accuracy: 1.0000
# 1/1 [==============================] - 3s 3s/step - loss: 0.0000e+00 - accuracy: 1.0000
# loss: 0.0000
# accuracy: 1.0000

# %%
# Model Summary
model.summary()
# Out:
# Model: "gradient_boosted_trees_model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
# =================================================================
# Total params: 1 (1.00 Byte)
# Trainable params: 0 (0.00 Byte)
# Non-trainable params: 1 (1.00 Byte)
# _________________________________________________________________
# Type: "GRADIENT_BOOSTED_TREES"
# Task: CLASSIFICATION
# Label: "__LABEL"
#
# Input Features (34):
# 	10Percentile
# 	90Percentile
# 	Energy
# 	Entropy
# 	GrayLevelNonUniformity
# 	GrayLevelNonUniformityNormalized
# 	GrayLevelVariance
# 	HighGrayLevelRunEmphasis
# 	InterquartileRange
# 	Kurtosis
# 	LongRunEmphasis
# 	LongRunHighGrayLevelEmphasis
# 	LongRunLowGrayLevelEmphasis
# 	LowGrayLevelRunEmphasis
# 	Maximum
# 	Mean
# 	MeanAbsoluteDeviation
# 	Median
# 	Minimum
# 	Range
# 	RobustMeanAbsoluteDeviation
# 	RootMeanSquared
# 	RunEntropy
# 	RunLengthNonUniformity
# 	RunLengthNonUniformityNormalized
# 	RunPercentage
# 	RunVariance
# 	ShortRunEmphasis
# 	ShortRunHighGrayLevelEmphasis
# 	ShortRunLowGrayLevelEmphasis
# 	Skewness
# 	TotalEnergy
# 	Uniformity
# 	Variance
#
# Trained with weights
#
# Variable Importance: INV_MEAN_MIN_DEPTH:
#     1. "GrayLevelNonUniformityNormalized"  0.408246 ################
#     2.      "LongRunLowGrayLevelEmphasis"  0.285613 #######
#     3.     "LongRunHighGrayLevelEmphasis"  0.250982 ####
#     4.                       "RunEntropy"  0.217562 ##
#     5.     "ShortRunLowGrayLevelEmphasis"  0.214949 #
#     6.                "GrayLevelVariance"  0.210758 #
#     7.                    "RunPercentage"  0.209714 #
#     8.               "InterquartileRange"  0.201792
#     9.          "LowGrayLevelRunEmphasis"  0.200553
#    10.                 "ShortRunEmphasis"  0.199514
#    11.    "ShortRunHighGrayLevelEmphasis"  0.196697
#    12.           "GrayLevelNonUniformity"  0.195789
#    13.                         "Variance"  0.194537
#    14.         "HighGrayLevelRunEmphasis"  0.194212
#    15.                  "LongRunEmphasis"  0.193275
#    16.                      "RunVariance"  0.192323
#    17. "RunLengthNonUniformityNormalized"  0.192213
#    18.           "RunLengthNonUniformity"  0.191672
#    19.                          "Maximum"  0.190750
#    20.                          "Minimum"  0.189811
#    21.                           "Energy"  0.189617
#    22.                            "Range"  0.189606
#    23.                       "Uniformity"  0.189599
#    24.                         "Kurtosis"  0.189490
#    25.                      "TotalEnergy"  0.189478
#    26.                  "RootMeanSquared"  0.189472
#    27.                          "Entropy"  0.189470
#    28.                     "90Percentile"  0.189450
#    29.                           "Median"  0.189441
#    30.                     "10Percentile"  0.189423
#    31.            "MeanAbsoluteDeviation"  0.189409
#    32.                         "Skewness"  0.189398
#    33.      "RobustMeanAbsoluteDeviation"  0.189381
#    34.                             "Mean"  0.189366
#
# Variable Importance: NUM_AS_ROOT:
#     1. "GrayLevelNonUniformityNormalized" 174.000000 ################
#     2.      "LongRunLowGrayLevelEmphasis" 113.000000 #########
#     3.                    "RunPercentage" 13.000000
#
# Variable Importance: NUM_NODES:
#     1.     "LongRunHighGrayLevelEmphasis" 591.000000 ################
#     2.      "LongRunLowGrayLevelEmphasis" 580.000000 ###############
#     3. "GrayLevelNonUniformityNormalized" 550.000000 ##############
#     4.     "ShortRunLowGrayLevelEmphasis" 452.000000 ############
#     5.                       "RunEntropy" 435.000000 ###########
#     6.                "GrayLevelVariance" 361.000000 #########
#     7.                         "Variance" 314.000000 ########
#     8.    "ShortRunHighGrayLevelEmphasis" 245.000000 ######
#     9.                    "RunPercentage" 232.000000 ######
#    10.               "InterquartileRange" 218.000000 #####
#    11.           "GrayLevelNonUniformity" 216.000000 #####
#    12.                 "ShortRunEmphasis" 194.000000 #####
#    13.                      "RunVariance" 184.000000 ####
#    14.         "HighGrayLevelRunEmphasis" 160.000000 ####
#    15.          "LowGrayLevelRunEmphasis" 160.000000 ####
#    16. "RunLengthNonUniformityNormalized" 149.000000 ###
#    17.           "RunLengthNonUniformity" 114.000000 ##
#    18.                  "LongRunEmphasis" 77.000000 #
#    19.                          "Maximum" 62.000000 #
#    20.                          "Minimum" 50.000000 #
#    21.                           "Energy" 13.000000
#    22.                         "Kurtosis" 13.000000
#    23.                            "Range" 13.000000
#    24.                       "Uniformity" 13.000000
#    25.                      "TotalEnergy" 11.000000
#    26.                     "10Percentile" 10.000000
#    27.                             "Mean"  9.000000
#    28.                  "RootMeanSquared"  9.000000
#    29.                          "Entropy"  8.000000
#    30.                           "Median"  8.000000
#    31.                         "Skewness"  7.000000
#    32.                     "90Percentile"  6.000000
#    33.            "MeanAbsoluteDeviation"  5.000000
#    34.      "RobustMeanAbsoluteDeviation"  5.000000
#
# Variable Importance: SUM_SCORE:
#     1.      "LongRunLowGrayLevelEmphasis" 1532.355022 ################
#     2.          "LowGrayLevelRunEmphasis" 270.452585 ##
#     3.     "ShortRunLowGrayLevelEmphasis" 109.948352 #
#     4. "GrayLevelNonUniformityNormalized"  0.000001
#     5.     "LongRunHighGrayLevelEmphasis"  0.000001
#     6.                    "RunPercentage"  0.000001
#     7.                 "ShortRunEmphasis"  0.000001
#     8.               "InterquartileRange"  0.000000
#     9.                "GrayLevelVariance"  0.000000
#    10.    "ShortRunHighGrayLevelEmphasis"  0.000000
#    11.           "GrayLevelNonUniformity"  0.000000
#    12.         "HighGrayLevelRunEmphasis"  0.000000
#    13.                          "Maximum"  0.000000
#    14.                         "Variance"  0.000000
#    15.                       "RunEntropy"  0.000000
#    16. "RunLengthNonUniformityNormalized"  0.000000
#    17.                      "RunVariance"  0.000000
#    18.           "RunLengthNonUniformity"  0.000000
#    19.                         "Kurtosis"  0.000000
#    20.                  "LongRunEmphasis"  0.000000
#    21.                       "Uniformity"  0.000000
#    22.                            "Range"  0.000000
#    23.                          "Minimum"  0.000000
#    24.                     "90Percentile"  0.000000
#    25.                      "TotalEnergy"  0.000000
#    26.                         "Skewness"  0.000000
#    27.                           "Energy"  0.000000
#    28.                          "Entropy"  0.000000
#    29.                     "10Percentile"  0.000000
#    30.                  "RootMeanSquared"  0.000000
#    31.                           "Median"  0.000000
#    32.            "MeanAbsoluteDeviation"  0.000000
#    33.                             "Mean"  0.000000
#    34.      "RobustMeanAbsoluteDeviation"  0.000000
#
#
#
# Loss: BINOMIAL_LOG_LIKELIHOOD
# Validation loss value: 1.63749e-06
# Number of trees per iteration: 1
# Node format: NOT_SET
# Number of trees: 300
# Total number of nodes: 11248
#
# Number of nodes by tree:
# Count: 300 Average: 37.4933 StdDev: 13.6087
# Min: 9 Max: 53 Ignored: 0
# ----------------------------------------------
# [  9, 11)   1   0.33%   0.33%
# [ 11, 13)   5   1.67%   2.00%
# [ 13, 15)  18   6.00%   8.00% ##
# [ 15, 18)  43  14.33%  22.33% ####
# [ 18, 20)   8   2.67%  25.00% #
# [ 20, 22)   3   1.00%  26.00%
# [ 22, 24)   1   0.33%  26.33%
# [ 24, 27)   1   0.33%  26.67%
# [ 27, 29)   1   0.33%  27.00%
# [ 29, 31)   0   0.00%  27.00%
# [ 31, 33)   1   0.33%  27.33%
# [ 33, 36)   2   0.67%  28.00%
# [ 36, 38)   1   0.33%  28.33%
# [ 38, 40)   2   0.67%  29.00%
# [ 40, 42)  10   3.33%  32.33% #
# [ 42, 45)  25   8.33%  40.67% ##
# [ 45, 47) 105  35.00%  75.67% ##########
# [ 47, 49)  34  11.33%  87.00% ###
# [ 49, 51)  27   9.00%  96.00% ###
# [ 51, 53]  12   4.00% 100.00% #
#
# Depth by leafs:
# Count: 5774 Average: 4.52251 StdDev: 0.762674
# Min: 1 Max: 5 Ignored: 0
# ----------------------------------------------
# [ 1, 2)    1   0.02%   0.02%
# [ 2, 3)  105   1.82%   1.84%
# [ 3, 4)  638  11.05%  12.89% ##
# [ 4, 5) 1162  20.12%  33.01% ###
# [ 5, 5] 3868  66.99% 100.00% ##########
#
# Number of training obs by leaf:
# Count: 5774 Average: 73.5712 StdDev: 198.247
# Min: 5 Max: 1053 Ignored: 0
# ----------------------------------------------
# [    5,   57) 4955  85.82%  85.82% ##########
# [   57,  109)   50   0.87%  86.68%
# [  109,  162)  175   3.03%  89.71%
# [  162,  214)   84   1.45%  91.17%
# [  214,  267)   50   0.87%  92.03%
# [  267,  319)   42   0.73%  92.76%
# [  319,  372)   69   1.20%  93.96%
# [  372,  424)    0   0.00%  93.96%
# [  424,  477)    1   0.02%  93.97%
# [  477,  529)   45   0.78%  94.75%
# [  529,  581)    7   0.12%  94.87%
# [  581,  634)   25   0.43%  95.31%
# [  634,  686)   12   0.21%  95.51%
# [  686,  739)   88   1.52%  97.04%
# [  739,  791)   20   0.35%  97.38%
# [  791,  844)   25   0.43%  97.82%
# [  844,  896)    1   0.02%  97.84%
# [  896,  949)    0   0.00%  97.84%
# [  949, 1001)   27   0.47%  98.30%
# [ 1001, 1053]   98   1.70% 100.00%
#
# Attribute in nodes:
# 	591 : LongRunHighGrayLevelEmphasis [NUMERICAL]
# 	580 : LongRunLowGrayLevelEmphasis [NUMERICAL]
# 	550 : GrayLevelNonUniformityNormalized [NUMERICAL]
# 	452 : ShortRunLowGrayLevelEmphasis [NUMERICAL]
# 	435 : RunEntropy [NUMERICAL]
# 	361 : GrayLevelVariance [NUMERICAL]
# 	314 : Variance [NUMERICAL]
# 	245 : ShortRunHighGrayLevelEmphasis [NUMERICAL]
# 	232 : RunPercentage [NUMERICAL]
# 	218 : InterquartileRange [NUMERICAL]
# 	216 : GrayLevelNonUniformity [NUMERICAL]
# 	194 : ShortRunEmphasis [NUMERICAL]
# 	184 : RunVariance [NUMERICAL]
# 	160 : LowGrayLevelRunEmphasis [NUMERICAL]
# 	160 : HighGrayLevelRunEmphasis [NUMERICAL]
# 	149 : RunLengthNonUniformityNormalized [NUMERICAL]
# 	114 : RunLengthNonUniformity [NUMERICAL]
# 	77 : LongRunEmphasis [NUMERICAL]
# 	62 : Maximum [NUMERICAL]
# 	50 : Minimum [NUMERICAL]
# 	13 : Uniformity [NUMERICAL]
# 	13 : Range [NUMERICAL]
# 	13 : Kurtosis [NUMERICAL]
# 	13 : Energy [NUMERICAL]
# 	11 : TotalEnergy [NUMERICAL]
# 	10 : 10Percentile [NUMERICAL]
# 	9 : RootMeanSquared [NUMERICAL]
# 	9 : Mean [NUMERICAL]
# 	8 : Median [NUMERICAL]
# 	8 : Entropy [NUMERICAL]
# 	7 : Skewness [NUMERICAL]
# 	6 : 90Percentile [NUMERICAL]
# 	5 : RobustMeanAbsoluteDeviation [NUMERICAL]
# 	5 : MeanAbsoluteDeviation [NUMERICAL]
#
# Attribute in nodes with depth <= 0:
# 	174 : GrayLevelNonUniformityNormalized [NUMERICAL]
# 	113 : LongRunLowGrayLevelEmphasis [NUMERICAL]
# 	13 : RunPercentage [NUMERICAL]
#
# Attribute in nodes with depth <= 1:
# 	190 : GrayLevelNonUniformityNormalized [NUMERICAL]
# 	178 : LongRunHighGrayLevelEmphasis [NUMERICAL]
# 	155 : LongRunLowGrayLevelEmphasis [NUMERICAL]
# 	107 : RunEntropy [NUMERICAL]
# 	78 : GrayLevelVariance [NUMERICAL]
# 	45 : LowGrayLevelRunEmphasis [NUMERICAL]
# 	44 : ShortRunLowGrayLevelEmphasis [NUMERICAL]
# 	39 : ShortRunEmphasis [NUMERICAL]
# 	30 : RunPercentage [NUMERICAL]
# 	6 : ShortRunHighGrayLevelEmphasis [NUMERICAL]
# 	6 : RunLengthNonUniformityNormalized [NUMERICAL]
# 	6 : RunLengthNonUniformity [NUMERICAL]
# 	6 : LongRunEmphasis [NUMERICAL]
# 	5 : GrayLevelNonUniformity [NUMERICAL]
# 	2 : RunVariance [NUMERICAL]
# 	2 : HighGrayLevelRunEmphasis [NUMERICAL]
#
# Attribute in nodes with depth <= 2:
# 	316 : GrayLevelNonUniformityNormalized [NUMERICAL]
# 	311 : LongRunHighGrayLevelEmphasis [NUMERICAL]
# 	297 : LongRunLowGrayLevelEmphasis [NUMERICAL]
# 	136 : ShortRunLowGrayLevelEmphasis [NUMERICAL]
# 	131 : GrayLevelVariance [NUMERICAL]
# 	126 : RunEntropy [NUMERICAL]
# 	121 : RunPercentage [NUMERICAL]
# 	80 : InterquartileRange [NUMERICAL]
# 	68 : ShortRunEmphasis [NUMERICAL]
# 	64 : ShortRunHighGrayLevelEmphasis [NUMERICAL]
# 	57 : LowGrayLevelRunEmphasis [NUMERICAL]
# 	43 : LongRunEmphasis [NUMERICAL]
# 	37 : HighGrayLevelRunEmphasis [NUMERICAL]
# 	34 : RunLengthNonUniformityNormalized [NUMERICAL]
# 	30 : GrayLevelNonUniformity [NUMERICAL]
# 	27 : RunLengthNonUniformity [NUMERICAL]
# 	20 : Variance [NUMERICAL]
# 	15 : RunVariance [NUMERICAL]
# 	13 : Maximum [NUMERICAL]
# 	7 : Energy [NUMERICAL]
# 	6 : Uniformity [NUMERICAL]
# 	6 : Range [NUMERICAL]
# 	6 : Median [NUMERICAL]
# 	5 : TotalEnergy [NUMERICAL]
# 	5 : RootMeanSquared [NUMERICAL]
# 	5 : 90Percentile [NUMERICAL]
# 	4 : Skewness [NUMERICAL]
# 	4 : MeanAbsoluteDeviation [NUMERICAL]
# 	4 : 10Percentile [NUMERICAL]
# 	3 : RobustMeanAbsoluteDeviation [NUMERICAL]
# 	3 : Minimum [NUMERICAL]
# 	3 : Mean [NUMERICAL]
# 	3 : Entropy [NUMERICAL]
# 	2 : Kurtosis [NUMERICAL]
#
# Attribute in nodes with depth <= 3:
# 	488 : LongRunHighGrayLevelEmphasis [NUMERICAL]
# 	404 : ShortRunLowGrayLevelEmphasis [NUMERICAL]
# 	401 : GrayLevelNonUniformityNormalized [NUMERICAL]
# 	359 : LongRunLowGrayLevelEmphasis [NUMERICAL]
# 	351 : RunEntropy [NUMERICAL]
# 	199 : GrayLevelVariance [NUMERICAL]
# 	197 : InterquartileRange [NUMERICAL]
# 	160 : GrayLevelNonUniformity [NUMERICAL]
# 	157 : RunPercentage [NUMERICAL]
# 	118 : Variance [NUMERICAL]
# 	110 : LowGrayLevelRunEmphasis [NUMERICAL]
# 	94 : ShortRunEmphasis [NUMERICAL]
# 	83 : ShortRunHighGrayLevelEmphasis [NUMERICAL]
# 	67 : HighGrayLevelRunEmphasis [NUMERICAL]
# 	63 : RunLengthNonUniformityNormalized [NUMERICAL]
# 	59 : RunLengthNonUniformity [NUMERICAL]
# 	54 : LongRunEmphasis [NUMERICAL]
# 	43 : Maximum [NUMERICAL]
# 	25 : RunVariance [NUMERICAL]
# 	10 : TotalEnergy [NUMERICAL]
# 	10 : 10Percentile [NUMERICAL]
# 	9 : Uniformity [NUMERICAL]
# 	9 : Energy [NUMERICAL]
# 	8 : RootMeanSquared [NUMERICAL]
# 	8 : Range [NUMERICAL]
# 	8 : Mean [NUMERICAL]
# 	7 : Skewness [NUMERICAL]
# 	7 : Minimum [NUMERICAL]
# 	7 : Median [NUMERICAL]
# 	6 : Entropy [NUMERICAL]
# 	6 : 90Percentile [NUMERICAL]
# 	5 : RobustMeanAbsoluteDeviation [NUMERICAL]
# 	5 : MeanAbsoluteDeviation [NUMERICAL]
# 	3 : Kurtosis [NUMERICAL]
#
# Attribute in nodes with depth <= 5:
# 	591 : LongRunHighGrayLevelEmphasis [NUMERICAL]
# 	580 : LongRunLowGrayLevelEmphasis [NUMERICAL]
# 	550 : GrayLevelNonUniformityNormalized [NUMERICAL]
# 	452 : ShortRunLowGrayLevelEmphasis [NUMERICAL]
# 	435 : RunEntropy [NUMERICAL]
# 	361 : GrayLevelVariance [NUMERICAL]
# 	314 : Variance [NUMERICAL]
# 	245 : ShortRunHighGrayLevelEmphasis [NUMERICAL]
# 	232 : RunPercentage [NUMERICAL]
# 	218 : InterquartileRange [NUMERICAL]
# 	216 : GrayLevelNonUniformity [NUMERICAL]
# 	194 : ShortRunEmphasis [NUMERICAL]
# 	184 : RunVariance [NUMERICAL]
# 	160 : LowGrayLevelRunEmphasis [NUMERICAL]
# 	160 : HighGrayLevelRunEmphasis [NUMERICAL]
# 	149 : RunLengthNonUniformityNormalized [NUMERICAL]
# 	114 : RunLengthNonUniformity [NUMERICAL]
# 	77 : LongRunEmphasis [NUMERICAL]
# 	62 : Maximum [NUMERICAL]
# 	50 : Minimum [NUMERICAL]
# 	13 : Uniformity [NUMERICAL]
# 	13 : Range [NUMERICAL]
# 	13 : Kurtosis [NUMERICAL]
# 	13 : Energy [NUMERICAL]
# 	11 : TotalEnergy [NUMERICAL]
# 	10 : 10Percentile [NUMERICAL]
# 	9 : RootMeanSquared [NUMERICAL]
# 	9 : Mean [NUMERICAL]
# 	8 : Median [NUMERICAL]
# 	8 : Entropy [NUMERICAL]
# 	7 : Skewness [NUMERICAL]
# 	6 : 90Percentile [NUMERICAL]
# 	5 : RobustMeanAbsoluteDeviation [NUMERICAL]
# 	5 : MeanAbsoluteDeviation [NUMERICAL]
#
# Condition type in nodes:
# 	5474 : HigherCondition
# Condition type in nodes with depth <= 0:
# 	300 : HigherCondition
# Condition type in nodes with depth <= 1:
# 	899 : HigherCondition
# Condition type in nodes with depth <= 2:
# 	1992 : HigherCondition
# Condition type in nodes with depth <= 3:
# 	3540 : HigherCondition
# Condition type in nodes with depth <= 5:
# 	5474 : HigherCondition
#
# Training logs:
# Number of iteration to final model: 300
# 	Iter:1 train-loss:1.196167 valid-loss:1.198494  train-accuracy:1.000000 valid-accuracy:1.000000
# 	Iter:2 train-loss:1.040555 valid-loss:1.042480  train-accuracy:1.000000 valid-accuracy:1.000000
# 	Iter:3 train-loss:0.910794 valid-loss:0.912411  train-accuracy:1.000000 valid-accuracy:1.000000
# 	Iter:4 train-loss:0.801111 valid-loss:0.802486  train-accuracy:1.000000 valid-accuracy:1.000000
# 	Iter:5 train-loss:0.707417 valid-loss:0.708597  train-accuracy:1.000000 valid-accuracy:1.000000
# 	Iter:6 train-loss:0.626707 valid-loss:0.627727  train-accuracy:1.000000 valid-accuracy:1.000000
# 	Iter:16 train-loss:0.206060 valid-loss:0.206357  train-accuracy:1.000000 valid-accuracy:1.000000
# 	Iter:26 train-loss:0.073107 valid-loss:0.073209  train-accuracy:1.000000 valid-accuracy:1.000000
# 	Iter:36 train-loss:0.026553 valid-loss:0.026590  train-accuracy:1.000000 valid-accuracy:1.000000
# 	Iter:46 train-loss:0.009723 valid-loss:0.009737  train-accuracy:1.000000 valid-accuracy:1.000000
# 	Iter:56 train-loss:0.003571 valid-loss:0.003576  train-accuracy:1.000000 valid-accuracy:1.000000
# 	Iter:66 train-loss:0.001313 valid-loss:0.001315  train-accuracy:1.000000 valid-accuracy:1.000000
# 	Iter:76 train-loss:0.000483 valid-loss:0.000484  train-accuracy:1.000000 valid-accuracy:1.000000
# 	Iter:86 train-loss:0.000179 valid-loss:0.000179  train-accuracy:1.000000 valid-accuracy:1.000000
# 	Iter:96 train-loss:0.000069 valid-loss:0.000069  train-accuracy:1.000000 valid-accuracy:1.000000
# 	Iter:106 train-loss:0.000028 valid-loss:0.000029  train-accuracy:1.000000 valid-accuracy:1.000000
# 	Iter:116 train-loss:0.000014 valid-loss:0.000015  train-accuracy:1.000000 valid-accuracy:1.000000
# 	Iter:126 train-loss:0.000008 valid-loss:0.000009  train-accuracy:1.000000 valid-accuracy:1.000000
# 	Iter:136 train-loss:0.000006 valid-loss:0.000007  train-accuracy:1.000000 valid-accuracy:1.000000
# 	Iter:146 train-loss:0.000005 valid-loss:0.000006  train-accuracy:1.000000 valid-accuracy:1.000000
# 	Iter:156 train-loss:0.000005 valid-loss:0.000005  train-accuracy:1.000000 valid-accuracy:1.000000
# 	Iter:166 train-loss:0.000004 valid-loss:0.000004  train-accuracy:1.000000 valid-accuracy:1.000000
# 	Iter:176 train-loss:0.000004 valid-loss:0.000004  train-accuracy:1.000000 valid-accuracy:1.000000
# 	Iter:186 train-loss:0.000003 valid-loss:0.000003  train-accuracy:1.000000 valid-accuracy:1.000000
# 	Iter:196 train-loss:0.000003 valid-loss:0.000003  train-accuracy:1.000000 valid-accuracy:1.000000
# 	Iter:206 train-loss:0.000003 valid-loss:0.000003  train-accuracy:1.000000 valid-accuracy:1.000000
# 	Iter:216 train-loss:0.000002 valid-loss:0.000003  train-accuracy:1.000000 valid-accuracy:1.000000
# 	Iter:226 train-loss:0.000002 valid-loss:0.000002  train-accuracy:1.000000 valid-accuracy:1.000000
# 	Iter:236 train-loss:0.000002 valid-loss:0.000002  train-accuracy:1.000000 valid-accuracy:1.000000
# 	Iter:246 train-loss:0.000002 valid-loss:0.000002  train-accuracy:1.000000 valid-accuracy:1.000000
# 	Iter:256 train-loss:0.000002 valid-loss:0.000002  train-accuracy:1.000000 valid-accuracy:1.000000
# 	Iter:266 train-loss:0.000002 valid-loss:0.000002  train-accuracy:1.000000 valid-accuracy:1.000000
# 	Iter:276 train-loss:0.000002 valid-loss:0.000002  train-accuracy:1.000000 valid-accuracy:1.000000
# 	Iter:286 train-loss:0.000002 valid-loss:0.000002  train-accuracy:1.000000 valid-accuracy:1.000000
# 	Iter:296 train-loss:0.000001 valid-loss:0.000002  train-accuracy:1.000000 valid-accuracy:1.000000

# %%
# Model features
model.make_inspector().features()
# Out:
# ["10Percentile" (1; #0),
#  "90Percentile" (1; #1),
#  "Energy" (1; #2),
#  "Entropy" (1; #3),
#  "GrayLevelNonUniformity" (1; #4),
#  "GrayLevelNonUniformityNormalized" (1; #5),
#  "GrayLevelVariance" (1; #6),
#  "HighGrayLevelRunEmphasis" (1; #7),
#  "InterquartileRange" (1; #8),
#  "Kurtosis" (1; #9),
#  "LongRunEmphasis" (1; #10),
#  "LongRunHighGrayLevelEmphasis" (1; #11),
#  "LongRunLowGrayLevelEmphasis" (1; #12),
#  "LowGrayLevelRunEmphasis" (1; #13),
#  "Maximum" (1; #14),
#  "Mean" (1; #15),
#  "MeanAbsoluteDeviation" (1; #16),
#  "Median" (1; #17),
#  "Minimum" (1; #18),
#  "Range" (1; #19),
#  "RobustMeanAbsoluteDeviation" (1; #20),
#  "RootMeanSquared" (1; #21),
#  "RunEntropy" (1; #22),
#  "RunLengthNonUniformity" (1; #23),
#  "RunLengthNonUniformityNormalized" (1; #24),
#  "RunPercentage" (1; #25),
#  "RunVariance" (1; #26),
#  "ShortRunEmphasis" (1; #27),
#  "ShortRunHighGrayLevelEmphasis" (1; #28),
#  "ShortRunLowGrayLevelEmphasis" (1; #29),
#  "Skewness" (1; #30),
#  "TotalEnergy" (1; #31),
#  "Uniformity" (1; #32),
#  "Variance" (1; #33)]

# %%
# Feature importance
model.make_inspector().variable_importances()
# Out:
# {'INV_MEAN_MIN_DEPTH': [("GrayLevelNonUniformityNormalized" (1; #5),
#    0.4082459098488787),
#   ("LongRunLowGrayLevelEmphasis" (1; #12), 0.28561302795226456),
#   ("LongRunHighGrayLevelEmphasis" (1; #11), 0.25098231782416613),
#   ("RunEntropy" (1; #22), 0.2175621833196467),
#   ("ShortRunLowGrayLevelEmphasis" (1; #29), 0.21494925555362324),
#   ("GrayLevelVariance" (1; #6), 0.2107577569722051),
#   ("RunPercentage" (1; #25), 0.2097140933223654),
#   ("InterquartileRange" (1; #8), 0.2017915232017319),
#   ("LowGrayLevelRunEmphasis" (1; #13), 0.20055271666966298),
#   ("ShortRunEmphasis" (1; #27), 0.19951433333741547),
#   ("ShortRunHighGrayLevelEmphasis" (1; #28), 0.1966973767684851),
#   ("GrayLevelNonUniformity" (1; #4), 0.19578902687413477),
#   ("Variance" (1; #33), 0.19453667513074732),
#   ("HighGrayLevelRunEmphasis" (1; #7), 0.1942117829447706),
#   ("LongRunEmphasis" (1; #10), 0.1932751216176021),
#   ("RunVariance" (1; #26), 0.19232293845328266),
#   ("RunLengthNonUniformityNormalized" (1; #24), 0.19221324568967796),
#   ("RunLengthNonUniformity" (1; #23), 0.19167225511743616),
#   ("Maximum" (1; #14), 0.19074989668613274),
#   ("Minimum" (1; #18), 0.18981077600338409),
#   ("Energy" (1; #2), 0.1896174808275977),
#   ("Range" (1; #19), 0.1896059276339419),
#   ("Uniformity" (1; #32), 0.18959870598731351),
#   ("Kurtosis" (1; #9), 0.18948988186178586),
#   ("TotalEnergy" (1; #31), 0.18947750521816684),
#   ("RootMeanSquared" (1; #21), 0.1894722858831658),
#   ("Entropy" (1; #3), 0.18947010153220123),
#   ("90Percentile" (1; #1), 0.18945034143217926),
#   ("Median" (1; #17), 0.18944061772289023),
#   ("10Percentile" (1; #0), 0.1894229128567246),
#   ("MeanAbsoluteDeviation" (1; #16), 0.1894091396495347),
#   ("Skewness" (1; #30), 0.1893979944316245),
#   ("RobustMeanAbsoluteDeviation" (1; #20), 0.18938134553726108),
#   ("Mean" (1; #15), 0.1893657066040214)],
#  'NUM_AS_ROOT': [("GrayLevelNonUniformityNormalized" (1; #5), 174.0),
#   ("LongRunLowGrayLevelEmphasis" (1; #12), 113.0),
#   ("RunPercentage" (1; #25), 13.0)],
#  'SUM_SCORE': [("LongRunLowGrayLevelEmphasis" (1; #12), 1532.3550216775127),
#   ("LowGrayLevelRunEmphasis" (1; #13), 270.4525854539613),
#   ("ShortRunLowGrayLevelEmphasis" (1; #29), 109.94835203768594),
#   ("GrayLevelNonUniformityNormalized" (1; #5), 1.3532632469292975e-06),
#   ("LongRunHighGrayLevelEmphasis" (1; #11), 1.0530428912866302e-06),
#   ("RunPercentage" (1; #25), 9.28320973423512e-07),
#   ("ShortRunEmphasis" (1; #27), 5.404271309499743e-07),
#   ("InterquartileRange" (1; #8), 3.256349776214254e-07),
#   ("GrayLevelVariance" (1; #6), 2.701763304237507e-07),
#   ("ShortRunHighGrayLevelEmphasis" (1; #28), 2.643070653143945e-07),
#   ("GrayLevelNonUniformity" (1; #4), 2.1226176104609255e-07),
#   ("HighGrayLevelRunEmphasis" (1; #7), 2.0555397534477915e-07),
#   ("Maximum" (1; #14), 8.281524659674204e-08),
#   ("Variance" (1; #33), 7.366646956566609e-08),
#   ("RunEntropy" (1; #22), 5.6839208457004236e-08),
#   ("RunLengthNonUniformityNormalized" (1; #24), 4.55700984127138e-08),
#   ("RunVariance" (1; #26), 4.068602381281278e-08),
#   ("RunLengthNonUniformity" (1; #23), 3.02985879508808e-08),
#   ("Kurtosis" (1; #9), 8.63358871543896e-09),
#   ("LongRunEmphasis" (1; #10), 7.094086254647162e-09),
#   ("Uniformity" (1; #32), 3.0784012238447252e-09),
#   ("Range" (1; #19), 1.8076752996455228e-09),
#   ("Minimum" (1; #18), 1.5063383894051844e-09),
#   ("90Percentile" (1; #1), 2.6687229749727925e-14),
#   ("TotalEnergy" (1; #31), 2.1920450150936342e-14),
#   ("Skewness" (1; #30), 1.1024201249801325e-14),
#   ("Energy" (1; #2), 5.461782452132153e-15),
#   ("Entropy" (1; #3), 4.808701761913213e-15),
#   ("10Percentile" (1; #0), 1.78544122963194e-15),
#   ("RootMeanSquared" (1; #21), 4.479200368229543e-16),
#   ("Median" (1; #17), 1.8977413870165083e-16),
#   ("MeanAbsoluteDeviation" (1; #16), 4.8573528676551527e-17),
#   ("Mean" (1; #15), 1.6740018189665324e-17),
#   ("RobustMeanAbsoluteDeviation" (1; #20), 3.7404975943595386e-18)],
#  'NUM_NODES': [("LongRunHighGrayLevelEmphasis" (1; #11), 591.0),
#   ("LongRunLowGrayLevelEmphasis" (1; #12), 580.0),
#   ("GrayLevelNonUniformityNormalized" (1; #5), 550.0),
#   ("ShortRunLowGrayLevelEmphasis" (1; #29), 452.0),
#   ("RunEntropy" (1; #22), 435.0),
#   ("GrayLevelVariance" (1; #6), 361.0),
#   ("Variance" (1; #33), 314.0),
#   ("ShortRunHighGrayLevelEmphasis" (1; #28), 245.0),
#   ("RunPercentage" (1; #25), 232.0),
#   ("InterquartileRange" (1; #8), 218.0),
#   ("GrayLevelNonUniformity" (1; #4), 216.0),
#   ("ShortRunEmphasis" (1; #27), 194.0),
#   ("RunVariance" (1; #26), 184.0),
#   ("HighGrayLevelRunEmphasis" (1; #7), 160.0),
#   ("LowGrayLevelRunEmphasis" (1; #13), 160.0),
#   ("RunLengthNonUniformityNormalized" (1; #24), 149.0),
#   ("RunLengthNonUniformity" (1; #23), 114.0),
#   ("LongRunEmphasis" (1; #10), 77.0),
#   ("Maximum" (1; #14), 62.0),
#   ("Minimum" (1; #18), 50.0),
#   ("Energy" (1; #2), 13.0),
#   ("Kurtosis" (1; #9), 13.0),
#   ("Range" (1; #19), 13.0),
#   ("Uniformity" (1; #32), 13.0),
#   ("TotalEnergy" (1; #31), 11.0),
#   ("10Percentile" (1; #0), 10.0),
#   ("Mean" (1; #15), 9.0),
#   ("RootMeanSquared" (1; #21), 9.0),
#   ("Entropy" (1; #3), 8.0),
#   ("Median" (1; #17), 8.0),
#   ("Skewness" (1; #30), 7.0),
#   ("90Percentile" (1; #1), 6.0),
#   ("MeanAbsoluteDeviation" (1; #16), 5.0),
#   ("RobustMeanAbsoluteDeviation" (1; #20), 5.0)]}

# %%
# Model self evaluation
model.make_inspector().evaluation()
# Out:
# Evaluation(num_examples=None, accuracy=1.0, loss=1.6374882534364588e-06, rmse=None, ndcg=None, aucs=None, auuc=None, qini=None)

# %%
logs = model.make_inspector().training_logs()

plt.figure(figsize=(12, 4))
plt.subplot(1, 2, 1)
plt.plot([log.num_trees for log in logs], [log.evaluation.accuracy for log in logs])
plt.xlabel("Number of trees")
plt.ylabel("Accuracy (out-of-bag)")
plt.subplot(1, 2, 2)
plt.plot([log.num_trees for log in logs], [log.evaluation.loss for log in logs])
plt.xlabel("Number of trees")
plt.ylabel("Logloss (out-of-bag)")
plt.show()

# %% [markdown]
# Calculate the score of our hold-out validation dataset

# %%
predictions = model.predict(val_ds)
y_true      = validation_data["label"]

from sklearn.metrics import roc_auc_score
ROC_AUC = roc_auc_score(y_true, predictions)
print("The ROC AUC score is %.5f" % ROC_AUC )
# Out:
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 68ms/step
# The ROC AUC score is 1.00000

# %%
# Compute binary classification metrics with sklearn
import numpy as np
from sklearn.metrics import (
    accuracy_score,
    precision_score,
    recall_score,
    f1_score,
    roc_auc_score,
    average_precision_score,
    confusion_matrix,
    classification_report,
    matthews_corrcoef,
    log_loss,
    brier_score_loss,
)

# Get predictions (probabilities or class labels)
preds = model.predict(test_ds)
# If model outputs probabilities, convert to labels by threshold 0.5
if preds.ndim == 2:
    # For TFDF classification, preds may be class probabilities with shape (N, 2)
    if preds.shape[1] == 2:
        pos_probs = preds[:, 1]
    else:
        # If single-probability column (positive class)
        pos_probs = preds[:, -1]
    y_pred = (pos_probs >= 0.5).astype(int)
else:
    # Already class labels
    y_pred = preds.astype(int)
    pos_probs = None

# Ground truth labels (must be 0/1 integers)
y_true = test_data["label"].astype(int).to_numpy()

# Core metrics
metrics = {}
metrics["accuracy"] = accuracy_score(y_true, y_pred)
metrics["precision"] = precision_score(y_true, y_pred, zero_division=0)
metrics["recall"] = recall_score(y_true, y_pred, zero_division=0)
metrics["f1"] = f1_score(y_true, y_pred, zero_division=0)
metrics["mcc"] = matthews_corrcoef(y_true, y_pred)

# Probabilistic metrics (only if we have probabilities)
if pos_probs is not None:
    metrics["roc_auc"] = roc_auc_score(y_true, pos_probs)
    metrics["pr_auc"] = average_precision_score(y_true, pos_probs)
    metrics["log_loss"] = log_loss(y_true, pos_probs, labels=[0,1])
    metrics["brier_score"] = brier_score_loss(y_true, pos_probs)

# Confusion matrix and detailed report
cm = confusion_matrix(y_true, y_pred, labels=[0,1])
report = classification_report(y_true, y_pred, digits=4)

print("Sklearn binary metrics:")
for k, v in metrics.items():
    print(f"{k}: {v:.4f}")
print("\nConfusion matrix:\n", cm)
print("\nClassification report:\n", report)
# Out:
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 76ms/step
# Sklearn binary metrics:
# accuracy: 1.0000
# precision: 1.0000
# recall: 1.0000
# f1: 1.0000
# mcc: 1.0000
# roc_auc: 1.0000
# pr_auc: 1.0000
# log_loss: 0.0000
# brier_score: 0.0000
#
# Confusion matrix:
#  [[327   0]
#  [  0 115]]
#
# Classification report:
#                precision    recall  f1-score   support
#
#            0     1.0000    1.0000    1.0000       327
#            1     1.0000    1.0000    1.0000       115
#
#     accuracy                         1.0000       442
#    macro avg     1.0000    1.0000    1.0000       442
# weighted avg     1.0000    1.0000    1.0000       442
