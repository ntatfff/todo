# %%
# Import packages and modules
import numpy  as np
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow_decision_forests as tfdf

from sklearn.model_selection import train_test_split
# Out:
# 2026-08-15 05:15:41.184334: I tensorflow/core/util/port.cc:113] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2026-08-15 05:15:41.558352: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2026-08-15 05:15:46.327694: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
# Check the version of TensorFlow Decision Forests
print("Found TensorFlow Decision Forests v" + tfdf.__version__)
# Out:
# Found TensorFlow Decision Forests v1.9.1

# %%
datasetPath = 'dataset/firstorder/kernel5/dataset.csv'

# %%
# Parameters
datasetPath = "dataset/ngtdm/kernel4/1.dataset.csv"

# %%
# train/validation/test = 70/10/20
dataset = pd.read_csv(datasetPath)

train_data, temp_data = train_test_split(dataset, test_size=0.3, random_state=42)
validation_data, test_data = train_test_split(temp_data, test_size=2/3, random_state=42)

# %%
from sklearn.utils.class_weight import compute_class_weight

# tinh class weight tren tap train
classes = np.array([0, 1])
weights = compute_class_weight(class_weight="balanced", classes=classes, y=train_data["label"])
class_weight = {0: weights[0], 1: weights[1]}

# gan sample_weight cho tung dong
train_data["sample_weight"] = train_data["label"].map(class_weight)
validation_data["sample_weight"] = validation_data["label"].map(class_weight)
test_data["sample_weight"] = test_data["label"].map(class_weight)

# Convert the dataset into a TensorFlow dataset.
train_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    train_data, label="label", weight="sample_weight"
)         
val_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    validation_data, label="label", weight="sample_weight"
)
test_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    test_data, label="label", weight="sample_weight"
)
# Out:
# 2026-08-15 05:15:59.497181: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:984] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2026-08-15 05:15:59.498718: W tensorflow/core/common_runtime/gpu/gpu_device.cc:2251] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...

# %%
import keras

# %%
# %%time

# Train a Random Forest model.
model = tfdf.keras.RandomForestModel()

# Add evaluation metrics
model.compile(
    metrics=["accuracy"]
)
model.fit(x=train_ds)

# # Train a Gradient Boosted Trees model.
# model = tfdf.keras.GradientBoostedTreesModel(num_trees=1500)
# model.fit(train_ds)
# Out:
# Use /tmp/tmp37_dgzvv as temporary training directory
# Reading training dataset...
# Training dataset read in 0:00:02.523064. Found 1554 examples.
# Training model...
# Model trained in 0:00:00.075859
# Compiling model...
# [INFO 26-08-15 05:16:02.2336 UTC kernel.cc:1233] Loading model from path /tmp/tmp37_dgzvv/model/ with prefix 7b5180bbdf164084
# [INFO 26-08-15 05:16:02.2496 UTC decision_forest.cc:734] Model loaded with 300 root(s), 12034 node(s), and 5 input feature(s).
# [INFO 26-08-15 05:16:02.2497 UTC abstract_model.cc:1362] Engine "RandomForestOptPred" built
# [INFO 26-08-15 05:16:02.2497 UTC kernel.cc:1061] Use fast generic engine
# Model compiled.
# CPU times: user 5.63 s, sys: 52.8 ms, total: 5.68 s
# Wall time: 6.5 s

# %%
# Evaluate the model
evaluate = model.evaluate(val_ds, return_dict=True)
print()

for name, value in evaluate.items():
    print(f"{name}: {value:.4f}")
# Out:
# WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 1/1 [==============================] - ETA: 0s - loss: 0.0000e+00 - accuracy: 0.9820
# 1/1 [==============================] - 3s 3s/step - loss: 0.0000e+00 - accuracy: 0.9820
# loss: 0.0000
# accuracy: 0.9820

# %%
# Model Summary
model.summary()
# Out:
# Model: "random_forest_model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
# =================================================================
# Total params: 1 (1.00 Byte)
# Trainable params: 0 (0.00 Byte)
# Non-trainable params: 1 (1.00 Byte)
# _________________________________________________________________
# Type: "RANDOM_FOREST"
# Task: CLASSIFICATION
# Label: "__LABEL"
#
# Input Features (5):
# 	Busyness
# 	Coarseness
# 	Complexity
# 	Contrast
# 	Strength
#
# Trained with weights
#
# Variable Importance: INV_MEAN_MIN_DEPTH:
#     1.   "Busyness"  0.810489 ################
#     2. "Coarseness"  0.320428 ###
#     3. "Complexity"  0.221280
#     4.   "Strength"  0.216376
#     5.   "Contrast"  0.189179
#
# Variable Importance: NUM_AS_ROOT:
#     1.   "Busyness" 249.000000 ################
#     2. "Coarseness" 51.000000
#
# Variable Importance: NUM_NODES:
#     1.   "Busyness" 1951.000000 ################
#     2.   "Strength" 1088.000000 ###
#     3. "Complexity" 1010.000000 #
#     4. "Coarseness" 932.000000
#     5.   "Contrast" 886.000000
#
# Variable Importance: SUM_SCORE:
#     1.   "Busyness" 231364.979770 ################
#     2. "Coarseness" 33459.388581 #
#     3.   "Strength" 20856.814830
#     4. "Complexity" 14103.523844
#     5.   "Contrast" 11932.208609
#
#
#
# Winner takes all: true
# Out-of-bag evaluation: accuracy:0.913302 logloss:0.2217
# Number of trees: 300
# Total number of nodes: 12034
#
# Number of nodes by tree:
# Count: 300 Average: 40.1133 StdDev: 4.69331
# Min: 29 Max: 55 Ignored: 0
# ----------------------------------------------
# [ 29, 30)  3   1.00%   1.00% #
# [ 30, 31)  0   0.00%   1.00%
# [ 31, 33) 10   3.33%   4.33% ##
# [ 33, 34) 14   4.67%   9.00% ###
# [ 34, 35)  0   0.00%   9.00%
# [ 35, 37) 32  10.67%  19.67% ######
# [ 37, 38) 38  12.67%  32.33% #######
# [ 38, 39)  0   0.00%  32.33%
# [ 39, 41) 53  17.67%  50.00% ##########
# [ 41, 42) 46  15.33%  65.33% #########
# [ 42, 43)  0   0.00%  65.33%
# [ 43, 45) 47  15.67%  81.00% #########
# [ 45, 46) 29   9.67%  90.67% #####
# [ 46, 47)  0   0.00%  90.67%
# [ 47, 49) 13   4.33%  95.00% ##
# [ 49, 50)  6   2.00%  97.00% #
# [ 50, 51)  0   0.00%  97.00%
# [ 51, 53)  7   2.33%  99.33% #
# [ 53, 54)  1   0.33%  99.67%
# [ 54, 55]  1   0.33% 100.00%
#
# Depth by leafs:
# Count: 6167 Average: 5.34279 StdDev: 1.85485
# Min: 1 Max: 12 Ignored: 0
# ----------------------------------------------
# [  1,  2)    2   0.03%   0.03%
# [  2,  3)  282   4.57%   4.61% ##
# [  3,  4)  693  11.24%  15.84% #####
# [  4,  5) 1198  19.43%  35.27% #########
# [  5,  6) 1348  21.86%  57.13% ##########
# [  6,  7) 1051  17.04%  74.17% ########
# [  7,  8)  773  12.53%  86.70% ######
# [  8,  9)  485   7.86%  94.57% ####
# [  9, 10)  216   3.50%  98.07% ##
# [ 10, 11)   84   1.36%  99.43% #
# [ 11, 12)   29   0.47%  99.90%
# [ 12, 12]    6   0.10% 100.00%
#
# Number of training obs by leaf:
# Count: 6167 Average: 75.5959 StdDev: 223.162
# Min: 5 Max: 1350 Ignored: 0
# ----------------------------------------------
# [    5,   72) 5528  89.64%  89.64% ##########
# [   72,  139)   50   0.81%  90.45%
# [  139,  206)   37   0.60%  91.05%
# [  206,  274)   83   1.35%  92.40%
# [  274,  341)   46   0.75%  93.14%
# [  341,  408)   96   1.56%  94.70%
# [  408,  476)   22   0.36%  95.05%
# [  476,  543)    7   0.11%  95.17%
# [  543,  610)    2   0.03%  95.20%
# [  610,  678)    1   0.02%  95.22%
# [  678,  745)    5   0.08%  95.30%
# [  745,  812)    8   0.13%  95.43%
# [  812,  879)   11   0.18%  95.61%
# [  879,  947)   87   1.41%  97.02%
# [  947, 1014)   55   0.89%  97.91%
# [ 1014, 1081)   29   0.47%  98.38%
# [ 1081, 1149)   60   0.97%  99.35%
# [ 1149, 1216)   15   0.24%  99.59%
# [ 1216, 1283)   11   0.18%  99.77%
# [ 1283, 1350]   14   0.23% 100.00%
#
# Attribute in nodes:
# 	1951 : Busyness [NUMERICAL]
# 	1088 : Strength [NUMERICAL]
# 	1010 : Complexity [NUMERICAL]
# 	932 : Coarseness [NUMERICAL]
# 	886 : Contrast [NUMERICAL]
#
# Attribute in nodes with depth <= 0:
# 	249 : Busyness [NUMERICAL]
# 	51 : Coarseness [NUMERICAL]
#
# Attribute in nodes with depth <= 1:
# 	581 : Busyness [NUMERICAL]
# 	215 : Coarseness [NUMERICAL]
# 	38 : Contrast [NUMERICAL]
# 	38 : Complexity [NUMERICAL]
# 	26 : Strength [NUMERICAL]
#
# Attribute in nodes with depth <= 2:
# 	934 : Busyness [NUMERICAL]
# 	332 : Coarseness [NUMERICAL]
# 	218 : Complexity [NUMERICAL]
# 	210 : Strength [NUMERICAL]
# 	118 : Contrast [NUMERICAL]
#
# Attribute in nodes with depth <= 3:
# 	1252 : Busyness [NUMERICAL]
# 	478 : Coarseness [NUMERICAL]
# 	472 : Complexity [NUMERICAL]
# 	469 : Strength [NUMERICAL]
# 	276 : Contrast [NUMERICAL]
#
# Attribute in nodes with depth <= 5:
# 	1714 : Busyness [NUMERICAL]
# 	885 : Strength [NUMERICAL]
# 	800 : Complexity [NUMERICAL]
# 	746 : Coarseness [NUMERICAL]
# 	670 : Contrast [NUMERICAL]
#
# Condition type in nodes:
# 	5867 : HigherCondition
# Condition type in nodes with depth <= 0:
# 	300 : HigherCondition
# Condition type in nodes with depth <= 1:
# 	898 : HigherCondition
# Condition type in nodes with depth <= 2:
# 	1812 : HigherCondition
# Condition type in nodes with depth <= 3:
# 	2947 : HigherCondition
# Condition type in nodes with depth <= 5:
# 	4815 : HigherCondition
# Node format: NOT_SET
#
# Training OOB:
# 	trees: 1, Out-of-bag evaluation: accuracy:0.881536 logloss:4.26989
# 	trees: 12, Out-of-bag evaluation: accuracy:0.892644 logloss:3.24101
# 	trees: 22, Out-of-bag evaluation: accuracy:0.871204 logloss:1.16879
# 	trees: 32, Out-of-bag evaluation: accuracy:0.890754 logloss:0.795806
# 	trees: 42, Out-of-bag evaluation: accuracy:0.901513 logloss:0.392226
# 	trees: 52, Out-of-bag evaluation: accuracy:0.895619 logloss:0.399435
# 	trees: 62, Out-of-bag evaluation: accuracy:0.896305 logloss:0.22716
# 	trees: 72, Out-of-bag evaluation: accuracy:0.90117 logloss:0.223307
# 	trees: 83, Out-of-bag evaluation: accuracy:0.912273 logloss:0.21768
# 	trees: 93, Out-of-bag evaluation: accuracy:0.917824 logloss:0.219324
# 	trees: 103, Out-of-bag evaluation: accuracy:0.918167 logloss:0.218743
# 	trees: 113, Out-of-bag evaluation: accuracy:0.917824 logloss:0.221962
# 	trees: 123, Out-of-bag evaluation: accuracy:0.912616 logloss:0.226667
# 	trees: 133, Out-of-bag evaluation: accuracy:0.912616 logloss:0.226547
# 	trees: 143, Out-of-bag evaluation: accuracy:0.912616 logloss:0.212814
# 	trees: 153, Out-of-bag evaluation: accuracy:0.90775 logloss:0.215332
# 	trees: 163, Out-of-bag evaluation: accuracy:0.912616 logloss:0.217885
# 	trees: 173, Out-of-bag evaluation: accuracy:0.90775 logloss:0.218706
# 	trees: 183, Out-of-bag evaluation: accuracy:0.912959 logloss:0.217873
# 	trees: 193, Out-of-bag evaluation: accuracy:0.91851 logloss:0.218523
# 	trees: 203, Out-of-bag evaluation: accuracy:0.91851 logloss:0.218418
# 	trees: 214, Out-of-bag evaluation: accuracy:0.913645 logloss:0.219537
# 	trees: 224, Out-of-bag evaluation: accuracy:0.913645 logloss:0.220848
# 	trees: 234, Out-of-bag evaluation: accuracy:0.913302 logloss:0.221042
# 	trees: 244, Out-of-bag evaluation: accuracy:0.913302 logloss:0.221651
# 	trees: 254, Out-of-bag evaluation: accuracy:0.918167 logloss:0.220677
# 	trees: 264, Out-of-bag evaluation: accuracy:0.90775 logloss:0.219086
# 	trees: 274, Out-of-bag evaluation: accuracy:0.918167 logloss:0.220256
# 	trees: 285, Out-of-bag evaluation: accuracy:0.913302 logloss:0.220733
# 	trees: 296, Out-of-bag evaluation: accuracy:0.913302 logloss:0.222337
# 	trees: 300, Out-of-bag evaluation: accuracy:0.913302 logloss:0.2217

# %%
# Model features
model.make_inspector().features()
# Out:
# ["Busyness" (1; #0),
#  "Coarseness" (1; #1),
#  "Complexity" (1; #2),
#  "Contrast" (1; #3),
#  "Strength" (1; #4)]

# %%
# Feature importance
model.make_inspector().variable_importances()
# Out:
# {'INV_MEAN_MIN_DEPTH': [("Busyness" (1; #0), 0.8104894191783489),
#   ("Coarseness" (1; #1), 0.32042814115821555),
#   ("Complexity" (1; #2), 0.22128000048567747),
#   ("Strength" (1; #4), 0.21637584437963314),
#   ("Contrast" (1; #3), 0.18917870350884436)],
#  'SUM_SCORE': [("Busyness" (1; #0), 231364.9797698549),
#   ("Coarseness" (1; #1), 33459.38858112741),
#   ("Strength" (1; #4), 20856.81483021705),
#   ("Complexity" (1; #2), 14103.523844320334),
#   ("Contrast" (1; #3), 11932.20860873012)],
#  'NUM_AS_ROOT': [("Busyness" (1; #0), 249.0), ("Coarseness" (1; #1), 51.0)],
#  'NUM_NODES': [("Busyness" (1; #0), 1951.0),
#   ("Strength" (1; #4), 1088.0),
#   ("Complexity" (1; #2), 1010.0),
#   ("Coarseness" (1; #1), 932.0),
#   ("Contrast" (1; #3), 886.0)]}

# %%
# Model self evaluation
model.make_inspector().evaluation()
# Out:
# Evaluation(num_examples=1554, accuracy=0.9133016105164882, loss=0.22169965476767203, rmse=None, ndcg=None, aucs=None, auuc=None, qini=None)

# %%
logs = model.make_inspector().training_logs()

plt.figure(figsize=(12, 4))
plt.subplot(1, 2, 1)
plt.plot([log.num_trees for log in logs], [log.evaluation.accuracy for log in logs])
plt.xlabel("Number of trees")
plt.ylabel("Accuracy (out-of-bag)")
plt.subplot(1, 2, 2)
plt.plot([log.num_trees for log in logs], [log.evaluation.loss for log in logs])
plt.xlabel("Number of trees")
plt.ylabel("Logloss (out-of-bag)")
plt.show()

# %% [markdown]
# Calculate the score of our hold-out validation dataset

# %%
predictions = model.predict(val_ds)
y_true      = validation_data["label"]

from sklearn.metrics import roc_auc_score
ROC_AUC = roc_auc_score(y_true, predictions)
print("The ROC AUC score is %.5f" % ROC_AUC )
# Out:
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 57ms/step
# The ROC AUC score is 0.99066

# %%
# Compute binary classification metrics with sklearn
import numpy as np
from sklearn.metrics import (
    accuracy_score,
    precision_score,
    recall_score,
    f1_score,
    roc_auc_score,
    average_precision_score,
    confusion_matrix,
    classification_report,
    matthews_corrcoef,
    log_loss,
    brier_score_loss,
)

# Get predictions (probabilities or class labels)
preds = model.predict(test_ds)
# If model outputs probabilities, convert to labels by threshold 0.5
if preds.ndim == 2:
    # For TFDF classification, preds may be class probabilities with shape (N, 2)
    if preds.shape[1] == 2:
        pos_probs = preds[:, 1]
    else:
        # If single-probability column (positive class)
        pos_probs = preds[:, -1]
    y_pred = (pos_probs >= 0.5).astype(int)
else:
    # Already class labels
    y_pred = preds.astype(int)
    pos_probs = None

# Ground truth labels (must be 0/1 integers)
y_true = test_data["label"].astype(int).to_numpy()

# Core metrics
metrics = {}
metrics["accuracy"] = accuracy_score(y_true, y_pred)
metrics["precision"] = precision_score(y_true, y_pred, zero_division=0)
metrics["recall"] = recall_score(y_true, y_pred, zero_division=0)
metrics["f1"] = f1_score(y_true, y_pred, zero_division=0)
metrics["mcc"] = matthews_corrcoef(y_true, y_pred)

# Probabilistic metrics (only if we have probabilities)
if pos_probs is not None:
    metrics["roc_auc"] = roc_auc_score(y_true, pos_probs)
    metrics["pr_auc"] = average_precision_score(y_true, pos_probs)
    metrics["log_loss"] = log_loss(y_true, pos_probs, labels=[0,1])
    metrics["brier_score"] = brier_score_loss(y_true, pos_probs)

# Confusion matrix and detailed report
cm = confusion_matrix(y_true, y_pred, labels=[0,1])
report = classification_report(y_true, y_pred, digits=4)

print("Sklearn binary metrics:")
for k, v in metrics.items():
    print(f"{k}: {v:.4f}")
print("\nConfusion matrix:\n", cm)
print("\nClassification report:\n", report)
# Out:
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 55ms/step
# Sklearn binary metrics:
# accuracy: 0.9865
# precision: 0.8667
# recall: 0.9286
# f1: 0.8966
# mcc: 0.8899
# roc_auc: 0.9964
# pr_auc: 0.9617
# log_loss: 0.0405
# brier_score: 0.0112
#
# Confusion matrix:
#  [[412   4]
#  [  2  26]]
#
# Classification report:
#                precision    recall  f1-score   support
#
#            0     0.9952    0.9904    0.9928       416
#            1     0.8667    0.9286    0.8966        28
#
#     accuracy                         0.9865       444
#    macro avg     0.9309    0.9595    0.9447       444
# weighted avg     0.9871    0.9865    0.9867       444
