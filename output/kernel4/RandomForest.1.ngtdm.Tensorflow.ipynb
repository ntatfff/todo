# %%
# Import packages and modules
import numpy  as np
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow_decision_forests as tfdf

from sklearn.model_selection import train_test_split
# Out:
# 2026-08-12 05:56:13.986707: I tensorflow/core/util/port.cc:113] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2026-08-12 05:56:14.331809: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2026-08-12 05:56:18.948273: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
# Check the version of TensorFlow Decision Forests
print("Found TensorFlow Decision Forests v" + tfdf.__version__)
# Out:
# Found TensorFlow Decision Forests v1.9.1

# %%
datasetPath = 'dataset/firstorder/kernel5-radius5/dataset.csv'

# %%
# Parameters
datasetPath = "dataset/ngtdm/kernel4-radius4/1.dataset.csv"

# %%
# train/validation/test = 70/10/20
dataset = pd.read_csv(datasetPath)

train_data, temp_data = train_test_split(dataset, test_size=0.3, random_state=42)
validation_data, test_data = train_test_split(temp_data, test_size=2/3, random_state=42)

# %%
from sklearn.utils.class_weight import compute_class_weight

# tinh class weight tren tap train
classes = np.array([0, 1])
weights = compute_class_weight(class_weight="balanced", classes=classes, y=train_data["label"])
class_weight = {0: weights[0], 1: weights[1]}

# gan sample_weight cho tung dong
train_data["sample_weight"] = train_data["label"].map(class_weight)
validation_data["sample_weight"] = validation_data["label"].map(class_weight)
test_data["sample_weight"] = test_data["label"].map(class_weight)

# Convert the dataset into a TensorFlow dataset.
train_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    train_data, label="label", weight="sample_weight"
)         
val_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    validation_data, label="label", weight="sample_weight"
)
test_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    test_data, label="label", weight="sample_weight"
)
# Out:
# 2026-08-12 05:56:31.705555: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:984] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2026-08-12 05:56:31.707141: W tensorflow/core/common_runtime/gpu/gpu_device.cc:2251] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...

# %%
import keras

# %%
# %%time

# Train a Random Forest model.
model = tfdf.keras.RandomForestModel()

# Add evaluation metrics
model.compile(
    metrics=["accuracy"]
)
model.fit(x=train_ds)

# # Train a Gradient Boosted Trees model.
# model = tfdf.keras.GradientBoostedTreesModel(num_trees=1500)
# model.fit(train_ds)
# Out:
# Use /tmp/tmp4s0ygy31 as temporary training directory
# Reading training dataset...
# Training dataset read in 0:00:02.338131. Found 1336 examples.
# Training model...
# Model trained in 0:00:00.105798
# Compiling model...
# [INFO 26-08-12 05:56:34.2596 UTC kernel.cc:1233] Loading model from path /tmp/tmp4s0ygy31/model/ with prefix 9cd6db0862ea4989
# [INFO 26-08-12 05:56:34.2897 UTC decision_forest.cc:734] Model loaded with 300 root(s), 24906 node(s), and 5 input feature(s).
# [INFO 26-08-12 05:56:34.2898 UTC abstract_model.cc:1362] Engine "RandomForestOptPred" built
# [INFO 26-08-12 05:56:34.2898 UTC kernel.cc:1061] Use fast generic engine
# Model compiled.
# CPU times: user 5.78 s, sys: 141 ms, total: 5.92 s
# Wall time: 5.5 s

# %%
# Evaluate the model
evaluate = model.evaluate(val_ds, return_dict=True)
print()

for name, value in evaluate.items():
    print(f"{name}: {value:.4f}")
# Out:
# WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 1/1 [==============================] - ETA: 0s - loss: 0.0000e+00 - accuracy: 0.9215
# 1/1 [==============================] - 3s 3s/step - loss: 0.0000e+00 - accuracy: 0.9215
# loss: 0.0000
# accuracy: 0.9215

# %%
# Model Summary
model.summary()
# Out:
# Model: "random_forest_model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
# =================================================================
# Total params: 1 (1.00 Byte)
# Trainable params: 0 (0.00 Byte)
# Non-trainable params: 1 (1.00 Byte)
# _________________________________________________________________
# Type: "RANDOM_FOREST"
# Task: CLASSIFICATION
# Label: "__LABEL"
#
# Input Features (5):
# 	Busyness
# 	Coarseness
# 	Complexity
# 	Contrast
# 	Strength
#
# Trained with weights
#
# Variable Importance: INV_MEAN_MIN_DEPTH:
#     1.   "Busyness"  0.778412 ################
#     2. "Complexity"  0.280695 ##
#     3. "Coarseness"  0.225106
#     4.   "Contrast"  0.193010
#     5.   "Strength"  0.189035
#
# Variable Importance: NUM_AS_ROOT:
#     1.   "Busyness" 234.000000 ################
#     2. "Coarseness" 66.000000
#
# Variable Importance: NUM_NODES:
#     1.   "Busyness" 3470.000000 ################
#     2. "Complexity" 2691.000000 #######
#     3.   "Strength" 2238.000000 ###
#     4.   "Contrast" 1966.000000
#     5. "Coarseness" 1938.000000
#
# Variable Importance: SUM_SCORE:
#     1.   "Busyness" 132643.185681 ################
#     2. "Complexity" 44320.477887 ###
#     3. "Coarseness" 30394.335941 #
#     4.   "Contrast" 23619.217191
#     5.   "Strength" 22974.995075
#
#
#
# Winner takes all: true
# Out-of-bag evaluation: accuracy:0.873222 logloss:0.502408
# Number of trees: 300
# Total number of nodes: 24906
#
# Number of nodes by tree:
# Count: 300 Average: 83.02 StdDev: 7.76743
# Min: 57 Max: 107 Ignored: 0
# ----------------------------------------------
# [  57,  59)  1   0.33%   0.33%
# [  59,  62)  1   0.33%   0.67%
# [  62,  64)  1   0.33%   1.00%
# [  64,  67)  1   0.33%   1.33%
# [  67,  69)  4   1.33%   2.67% #
# [  69,  72) 14   4.67%   7.33% ###
# [  72,  74) 12   4.00%  11.33% ##
# [  74,  77) 20   6.67%  18.00% ####
# [  77,  79) 25   8.33%  26.33% ####
# [  79,  82) 52  17.33%  43.67% #########
# [  82,  85) 38  12.67%  56.33% #######
# [  85,  87) 21   7.00%  63.33% ####
# [  87,  90) 56  18.67%  82.00% ##########
# [  90,  92) 20   6.67%  88.67% ####
# [  92,  95) 14   4.67%  93.33% ###
# [  95,  97)  6   2.00%  95.33% #
# [  97, 100) 10   3.33%  98.67% ##
# [ 100, 102)  1   0.33%  99.00%
# [ 102, 105)  1   0.33%  99.33%
# [ 105, 107]  2   0.67% 100.00%
#
# Depth by leafs:
# Count: 12603 Average: 6.09244 StdDev: 1.54335
# Min: 2 Max: 13 Ignored: 0
# ----------------------------------------------
# [  2,  3)   12   0.10%   0.10%
# [  3,  4)  248   1.97%   2.06% #
# [  4,  5) 1565  12.42%  14.48% #####
# [  5,  6) 2979  23.64%  38.12% #########
# [  6,  7) 3157  25.05%  63.17% ##########
# [  7,  8) 2467  19.57%  82.74% ########
# [  8,  9) 1309  10.39%  93.13% ####
# [  9, 10)  593   4.71%  97.83% ##
# [ 10, 11)  194   1.54%  99.37% #
# [ 11, 12)   50   0.40%  99.77%
# [ 12, 13)   27   0.21%  99.98%
# [ 13, 13]    2   0.02% 100.00%
#
# Number of training obs by leaf:
# Count: 12603 Average: 31.802 StdDev: 97.0159
# Min: 5 Max: 861 Ignored: 0
# ----------------------------------------------
# [   5,  47) 11423  90.64%  90.64% ##########
# [  47,  90)   484   3.84%  94.48%
# [  90, 133)   120   0.95%  95.43%
# [ 133, 176)   134   1.06%  96.49%
# [ 176, 219)    80   0.63%  97.13%
# [ 219, 262)    28   0.22%  97.35%
# [ 262, 304)    17   0.13%  97.48%
# [ 304, 347)    15   0.12%  97.60%
# [ 347, 390)     3   0.02%  97.63%
# [ 390, 433)    10   0.08%  97.71%
# [ 433, 476)    16   0.13%  97.83%
# [ 476, 519)    21   0.17%  98.00%
# [ 519, 562)    57   0.45%  98.45%
# [ 562, 604)    40   0.32%  98.77%
# [ 604, 647)    41   0.33%  99.10%
# [ 647, 690)    53   0.42%  99.52%
# [ 690, 733)    24   0.19%  99.71%
# [ 733, 776)    21   0.17%  99.87%
# [ 776, 819)    10   0.08%  99.95%
# [ 819, 861]     6   0.05% 100.00%
#
# Attribute in nodes:
# 	3470 : Busyness [NUMERICAL]
# 	2691 : Complexity [NUMERICAL]
# 	2238 : Strength [NUMERICAL]
# 	1966 : Contrast [NUMERICAL]
# 	1938 : Coarseness [NUMERICAL]
#
# Attribute in nodes with depth <= 0:
# 	234 : Busyness [NUMERICAL]
# 	66 : Coarseness [NUMERICAL]
#
# Attribute in nodes with depth <= 1:
# 	454 : Busyness [NUMERICAL]
# 	238 : Complexity [NUMERICAL]
# 	114 : Coarseness [NUMERICAL]
# 	80 : Contrast [NUMERICAL]
# 	14 : Strength [NUMERICAL]
#
# Attribute in nodes with depth <= 2:
# 	898 : Busyness [NUMERICAL]
# 	576 : Complexity [NUMERICAL]
# 	244 : Coarseness [NUMERICAL]
# 	190 : Strength [NUMERICAL]
# 	180 : Contrast [NUMERICAL]
#
# Attribute in nodes with depth <= 3:
# 	1469 : Busyness [NUMERICAL]
# 	1114 : Complexity [NUMERICAL]
# 	679 : Strength [NUMERICAL]
# 	502 : Coarseness [NUMERICAL]
# 	452 : Contrast [NUMERICAL]
#
# Attribute in nodes with depth <= 5:
# 	2771 : Busyness [NUMERICAL]
# 	2120 : Complexity [NUMERICAL]
# 	1686 : Strength [NUMERICAL]
# 	1375 : Coarseness [NUMERICAL]
# 	1358 : Contrast [NUMERICAL]
#
# Condition type in nodes:
# 	12303 : HigherCondition
# Condition type in nodes with depth <= 0:
# 	300 : HigherCondition
# Condition type in nodes with depth <= 1:
# 	900 : HigherCondition
# Condition type in nodes with depth <= 2:
# 	2088 : HigherCondition
# Condition type in nodes with depth <= 3:
# 	4216 : HigherCondition
# Condition type in nodes with depth <= 5:
# 	9310 : HigherCondition
# Node format: NOT_SET
#
# Training OOB:
# 	trees: 1, Out-of-bag evaluation: accuracy:0.822527 logloss:6.39677
# 	trees: 11, Out-of-bag evaluation: accuracy:0.828223 logloss:4.70947
# 	trees: 21, Out-of-bag evaluation: accuracy:0.874236 logloss:1.26467
# 	trees: 31, Out-of-bag evaluation: accuracy:0.875536 logloss:0.759925
# 	trees: 41, Out-of-bag evaluation: accuracy:0.871341 logloss:0.624365
# 	trees: 52, Out-of-bag evaluation: accuracy:0.870474 logloss:0.609841
# 	trees: 62, Out-of-bag evaluation: accuracy:0.86238 logloss:0.614471
# 	trees: 72, Out-of-bag evaluation: accuracy:0.857752 logloss:0.617851
# 	trees: 82, Out-of-bag evaluation: accuracy:0.863247 logloss:0.62107
# 	trees: 92, Out-of-bag evaluation: accuracy:0.869608 logloss:0.620609
# 	trees: 102, Out-of-bag evaluation: accuracy:0.866861 logloss:0.604548
# 	trees: 112, Out-of-bag evaluation: accuracy:0.868308 logloss:0.602499
# 	trees: 122, Out-of-bag evaluation: accuracy:0.868741 logloss:0.602718
# 	trees: 132, Out-of-bag evaluation: accuracy:0.866427 logloss:0.603306
# 	trees: 142, Out-of-bag evaluation: accuracy:0.864113 logloss:0.602636
# 	trees: 152, Out-of-bag evaluation: accuracy:0.867727 logloss:0.589741
# 	trees: 162, Out-of-bag evaluation: accuracy:0.866861 logloss:0.589879
# 	trees: 172, Out-of-bag evaluation: accuracy:0.864113 logloss:0.590214
# 	trees: 182, Out-of-bag evaluation: accuracy:0.869175 logloss:0.588674
# 	trees: 192, Out-of-bag evaluation: accuracy:0.870908 logloss:0.58973
# 	trees: 203, Out-of-bag evaluation: accuracy:0.868594 logloss:0.502887
# 	trees: 213, Out-of-bag evaluation: accuracy:0.870908 logloss:0.503143
# 	trees: 223, Out-of-bag evaluation: accuracy:0.873222 logloss:0.501405
# 	trees: 233, Out-of-bag evaluation: accuracy:0.872788 logloss:0.499884
# 	trees: 243, Out-of-bag evaluation: accuracy:0.872355 logloss:0.500161
# 	trees: 253, Out-of-bag evaluation: accuracy:0.872355 logloss:0.500402
# 	trees: 263, Out-of-bag evaluation: accuracy:0.872355 logloss:0.501607
# 	trees: 273, Out-of-bag evaluation: accuracy:0.872355 logloss:0.501273
# 	trees: 284, Out-of-bag evaluation: accuracy:0.876402 logloss:0.501318
# 	trees: 294, Out-of-bag evaluation: accuracy:0.873222 logloss:0.501591
# 	trees: 300, Out-of-bag evaluation: accuracy:0.873222 logloss:0.502408

# %%
# Model features
model.make_inspector().features()
# Out:
# ["Busyness" (1; #0),
#  "Coarseness" (1; #1),
#  "Complexity" (1; #2),
#  "Contrast" (1; #3),
#  "Strength" (1; #4)]

# %%
# Feature importance
model.make_inspector().variable_importances()
# Out:
# {'INV_MEAN_MIN_DEPTH': [("Busyness" (1; #0), 0.7784121930711211),
#   ("Complexity" (1; #2), 0.2806953159118773),
#   ("Coarseness" (1; #1), 0.2251059988483087),
#   ("Contrast" (1; #3), 0.19301014695148982),
#   ("Strength" (1; #4), 0.1890347682603028)],
#  'NUM_AS_ROOT': [("Busyness" (1; #0), 234.0), ("Coarseness" (1; #1), 66.0)],
#  'SUM_SCORE': [("Busyness" (1; #0), 132643.18568074473),
#   ("Complexity" (1; #2), 44320.477886713175),
#   ("Coarseness" (1; #1), 30394.335941264828),
#   ("Contrast" (1; #3), 23619.217190893854),
#   ("Strength" (1; #4), 22974.995075464216)],
#  'NUM_NODES': [("Busyness" (1; #0), 3470.0),
#   ("Complexity" (1; #2), 2691.0),
#   ("Strength" (1; #4), 2238.0),
#   ("Contrast" (1; #3), 1966.0),
#   ("Coarseness" (1; #1), 1938.0)]}

# %%
# Model self evaluation
model.make_inspector().evaluation()
# Out:
# Evaluation(num_examples=1336, accuracy=0.8732216678879922, loss=0.5024081720694145, rmse=None, ndcg=None, aucs=None, auuc=None, qini=None)

# %%
logs = model.make_inspector().training_logs()

plt.figure(figsize=(12, 4))
plt.subplot(1, 2, 1)
plt.plot([log.num_trees for log in logs], [log.evaluation.accuracy for log in logs])
plt.xlabel("Number of trees")
plt.ylabel("Accuracy (out-of-bag)")
plt.subplot(1, 2, 2)
plt.plot([log.num_trees for log in logs], [log.evaluation.loss for log in logs])
plt.xlabel("Number of trees")
plt.ylabel("Logloss (out-of-bag)")
plt.show()

# %% [markdown]
# Calculate the score of our hold-out validation dataset

# %%
predictions = model.predict(val_ds)
y_true      = validation_data["label"]

from sklearn.metrics import roc_auc_score
ROC_AUC = roc_auc_score(y_true, predictions)
print("The ROC AUC score is %.5f" % ROC_AUC )
# Out:
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 57ms/step
# The ROC AUC score is 0.97979

# %%
# Compute binary classification metrics with sklearn
import numpy as np
from sklearn.metrics import (
    accuracy_score,
    precision_score,
    recall_score,
    f1_score,
    roc_auc_score,
    average_precision_score,
    confusion_matrix,
    classification_report,
    matthews_corrcoef,
    log_loss,
    brier_score_loss,
)

# Get predictions (probabilities or class labels)
preds = model.predict(test_ds)
# If model outputs probabilities, convert to labels by threshold 0.5
if preds.ndim == 2:
    # For TFDF classification, preds may be class probabilities with shape (N, 2)
    if preds.shape[1] == 2:
        pos_probs = preds[:, 1]
    else:
        # If single-probability column (positive class)
        pos_probs = preds[:, -1]
    y_pred = (pos_probs >= 0.5).astype(int)
else:
    # Already class labels
    y_pred = preds.astype(int)
    pos_probs = None

# Ground truth labels (must be 0/1 integers)
y_true = test_data["label"].astype(int).to_numpy()

# Core metrics
metrics = {}
metrics["accuracy"] = accuracy_score(y_true, y_pred)
metrics["precision"] = precision_score(y_true, y_pred, zero_division=0)
metrics["recall"] = recall_score(y_true, y_pred, zero_division=0)
metrics["f1"] = f1_score(y_true, y_pred, zero_division=0)
metrics["mcc"] = matthews_corrcoef(y_true, y_pred)

# Probabilistic metrics (only if we have probabilities)
if pos_probs is not None:
    metrics["roc_auc"] = roc_auc_score(y_true, pos_probs)
    metrics["pr_auc"] = average_precision_score(y_true, pos_probs)
    metrics["log_loss"] = log_loss(y_true, pos_probs, labels=[0,1])
    metrics["brier_score"] = brier_score_loss(y_true, pos_probs)

# Confusion matrix and detailed report
cm = confusion_matrix(y_true, y_pred, labels=[0,1])
report = classification_report(y_true, y_pred, digits=4)

print("Sklearn binary metrics:")
for k, v in metrics.items():
    print(f"{k}: {v:.4f}")
print("\nConfusion matrix:\n", cm)
print("\nClassification report:\n", report)
# Out:
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 59ms/step
# Sklearn binary metrics:
# accuracy: 0.9346
# precision: 0.7188
# recall: 0.8679
# f1: 0.7863
# mcc: 0.7527
# roc_auc: 0.9687
# pr_auc: 0.8062
# log_loss: 0.1757
# brier_score: 0.0528
#
# Confusion matrix:
#  [[311  18]
#  [  7  46]]
#
# Classification report:
#                precision    recall  f1-score   support
#
#            0     0.9780    0.9453    0.9614       329
#            1     0.7188    0.8679    0.7863        53
#
#     accuracy                         0.9346       382
#    macro avg     0.8484    0.9066    0.8738       382
# weighted avg     0.9420    0.9346    0.9371       382
