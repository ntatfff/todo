# %%
# Import packages and modules
import numpy  as np
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow_decision_forests as tfdf

from sklearn.model_selection import train_test_split
# Out:
# 2026-08-15 04:59:15.210095: I tensorflow/core/util/port.cc:113] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2026-08-15 04:59:15.590057: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2026-08-15 04:59:20.493302: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
# Check the version of TensorFlow Decision Forests
print("Found TensorFlow Decision Forests v" + tfdf.__version__)
# Out:
# Found TensorFlow Decision Forests v1.9.1

# %%
datasetPath = 'dataset/firstorder/kernel5/dataset.csv'

# %%
# Parameters
datasetPath = "dataset/gldm/kernel4/1.dataset.csv"

# %%
# train/validation/test = 70/10/20
dataset = pd.read_csv(datasetPath)

train_data, temp_data = train_test_split(dataset, test_size=0.3, random_state=42)
validation_data, test_data = train_test_split(temp_data, test_size=2/3, random_state=42)

# %%
from sklearn.utils.class_weight import compute_class_weight

# tinh class weight tren tap train
classes = np.array([0, 1])
weights = compute_class_weight(class_weight="balanced", classes=classes, y=train_data["label"])
class_weight = {0: weights[0], 1: weights[1]}

# gan sample_weight cho tung dong
train_data["sample_weight"] = train_data["label"].map(class_weight)
validation_data["sample_weight"] = validation_data["label"].map(class_weight)
test_data["sample_weight"] = test_data["label"].map(class_weight)

# Convert the dataset into a TensorFlow dataset.
train_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    train_data, label="label", weight="sample_weight"
)         
val_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    validation_data, label="label", weight="sample_weight"
)
test_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    test_data, label="label", weight="sample_weight"
)
# Out:
# 2026-08-15 04:59:33.581602: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:984] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2026-08-15 04:59:33.583022: W tensorflow/core/common_runtime/gpu/gpu_device.cc:2251] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...

# %%
import keras

# %%
# %%time

# Train a Gradient Boosted Trees model.
model = tfdf.keras.GradientBoostedTreesModel()

# Add evaluation metrics
model.compile(
    metrics=["accuracy"]
)
model.fit(x=train_ds)

# # Train a Gradient Boosted Trees model.
# model = tfdf.keras.GradientBoostedTreesModel(num_trees=1500)
# model.fit(train_ds)
# Out:
# Use /tmp/tmpy1l4mwzx as temporary training directory
# Reading training dataset...
# [WARNING 26-08-15 04:59:33.7355 UTC gradient_boosted_trees.cc:1840] "goss_alpha" set but "sampling_method" not equal to "GOSS".
# [WARNING 26-08-15 04:59:33.7358 UTC gradient_boosted_trees.cc:1851] "goss_beta" set but "sampling_method" not equal to "GOSS".
# [WARNING 26-08-15 04:59:33.7358 UTC gradient_boosted_trees.cc:1865] "selective_gradient_boosting_ratio" set but "sampling_method" not equal to "SELGB".
# Training dataset read in 0:00:02.666956. Found 1554 examples.
# Training model...
# Model trained in 0:00:00.441014
# Compiling model...
# [INFO 26-08-15 04:59:36.8730 UTC kernel.cc:1233] Loading model from path /tmp/tmpy1l4mwzx/model/ with prefix 1fd50cfa703548e5
# [INFO 26-08-15 04:59:36.8767 UTC quick_scorer_extended.cc:911] The binary was compiled without AVX2 support, but your CPU supports it. Enable it for faster model inference.
# [INFO 26-08-15 04:59:36.8769 UTC abstract_model.cc:1362] Engine "GradientBoostedTreesQuickScorerExtended" built
# [INFO 26-08-15 04:59:36.8769 UTC kernel.cc:1061] Use fast generic engine
# Model compiled.
# CPU times: user 6.23 s, sys: 536 ms, total: 6.77 s
# Wall time: 6.37 s

# %%
# Evaluate the model
evaluate = model.evaluate(val_ds, return_dict=True)
print()

for name, value in evaluate.items():
    print(f"{name}: {value:.4f}")
# Out:
# WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 1/1 [==============================] - ETA: 0s - loss: 0.0000e+00 - accuracy: 0.9775
# 1/1 [==============================] - 4s 4s/step - loss: 0.0000e+00 - accuracy: 0.9775
# loss: 0.0000
# accuracy: 0.9775

# %%
# Model Summary
model.summary()
# Out:
# Model: "gradient_boosted_trees_model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
# =================================================================
# Total params: 1 (1.00 Byte)
# Trainable params: 0 (0.00 Byte)
# Non-trainable params: 1 (1.00 Byte)
# _________________________________________________________________
# Type: "GRADIENT_BOOSTED_TREES"
# Task: CLASSIFICATION
# Label: "__LABEL"
#
# Input Features (14):
# 	DependenceEntropy
# 	DependenceNonUniformity
# 	DependenceNonUniformityNormalized
# 	DependenceVariance
# 	GrayLevelNonUniformity
# 	GrayLevelVariance
# 	HighGrayLevelEmphasis
# 	LargeDependenceEmphasis
# 	LargeDependenceHighGrayLevelEmphasis
# 	LargeDependenceLowGrayLevelEmphasis
# 	LowGrayLevelEmphasis
# 	SmallDependenceEmphasis
# 	SmallDependenceHighGrayLevelEmphasis
# 	SmallDependenceLowGrayLevelEmphasis
#
# Trained with weights
#
# Variable Importance: INV_MEAN_MIN_DEPTH:
#     1.                "HighGrayLevelEmphasis"  1.000000 ################
#     2.               "GrayLevelNonUniformity"  0.260893 #
#     3.                    "DependenceEntropy"  0.255346 #
#     4.  "LargeDependenceLowGrayLevelEmphasis"  0.229549
#     5.  "SmallDependenceLowGrayLevelEmphasis"  0.209023
#     6. "SmallDependenceHighGrayLevelEmphasis"  0.207814
#     7.                 "LowGrayLevelEmphasis"  0.199484
#     8. "LargeDependenceHighGrayLevelEmphasis"  0.198130
#     9.                   "DependenceVariance"  0.196343
#    10.              "SmallDependenceEmphasis"  0.192062
#    11.              "DependenceNonUniformity"  0.191365
#    12.    "DependenceNonUniformityNormalized"  0.191342
#    13.              "LargeDependenceEmphasis"  0.190664
#    14.                    "GrayLevelVariance"  0.189927
#
# Variable Importance: NUM_AS_ROOT:
#     1. "HighGrayLevelEmphasis" 82.000000
#
# Variable Importance: NUM_NODES:
#     1.                "HighGrayLevelEmphasis" 270.000000 ################
#     2.                    "DependenceEntropy" 221.000000 ############
#     3.  "LargeDependenceLowGrayLevelEmphasis" 175.000000 ##########
#     4.               "GrayLevelNonUniformity" 122.000000 ######
#     5. "SmallDependenceHighGrayLevelEmphasis" 107.000000 #####
#     6.  "SmallDependenceLowGrayLevelEmphasis" 97.000000 #####
#     7.                   "DependenceVariance" 65.000000 ###
#     8.                 "LowGrayLevelEmphasis" 58.000000 ##
#     9. "LargeDependenceHighGrayLevelEmphasis" 34.000000 #
#    10.              "SmallDependenceEmphasis" 22.000000
#    11.              "DependenceNonUniformity" 18.000000
#    12.    "DependenceNonUniformityNormalized" 18.000000
#    13.              "LargeDependenceEmphasis" 12.000000
#    14.                    "GrayLevelVariance" 10.000000
#
# Variable Importance: SUM_SCORE:
#     1.                "HighGrayLevelEmphasis" 1580.266375 ################
#     2.               "GrayLevelNonUniformity" 170.239281 #
#     3.  "LargeDependenceLowGrayLevelEmphasis" 65.373674
#     4.                   "DependenceVariance" 33.479315
#     5. "SmallDependenceHighGrayLevelEmphasis"  9.881639
#     6.  "SmallDependenceLowGrayLevelEmphasis"  6.359156
#     7. "LargeDependenceHighGrayLevelEmphasis"  3.614445
#     8.                    "DependenceEntropy"  2.852714
#     9.              "LargeDependenceEmphasis"  2.548840
#    10.              "DependenceNonUniformity"  2.324115
#    11.    "DependenceNonUniformityNormalized"  0.759162
#    12.                 "LowGrayLevelEmphasis"  0.237036
#    13.                    "GrayLevelVariance"  0.059635
#    14.              "SmallDependenceEmphasis"  0.017282
#
#
#
# Loss: BINOMIAL_LOG_LIKELIHOOD
# Validation loss value: 0.0154495
# Number of trees per iteration: 1
# Node format: NOT_SET
# Number of trees: 82
# Total number of nodes: 2540
#
# Number of nodes by tree:
# Count: 82 Average: 30.9756 StdDev: 5.12758
# Min: 23 Max: 43 Ignored: 0
# ----------------------------------------------
# [ 23, 24)  4   4.88%   4.88% ##
# [ 24, 25)  0   0.00%   4.88%
# [ 25, 26) 10  12.20%  17.07% ######
# [ 26, 27)  0   0.00%  17.07%
# [ 27, 28) 18  21.95%  39.02% ##########
# [ 28, 29)  0   0.00%  39.02%
# [ 29, 30)  8   9.76%  48.78% ####
# [ 30, 31)  0   0.00%  48.78%
# [ 31, 32) 11  13.41%  62.20% ######
# [ 32, 33)  0   0.00%  62.20%
# [ 33, 34)  5   6.10%  68.29% ###
# [ 34, 35)  0   0.00%  68.29%
# [ 35, 36)  6   7.32%  75.61% ###
# [ 36, 37)  0   0.00%  75.61%
# [ 37, 38) 12  14.63%  90.24% #######
# [ 38, 39)  0   0.00%  90.24%
# [ 39, 40)  6   7.32%  97.56% ###
# [ 40, 41)  0   0.00%  97.56%
# [ 41, 42)  0   0.00%  97.56%
# [ 42, 43]  2   2.44% 100.00% #
#
# Depth by leafs:
# Count: 1311 Average: 4.31274 StdDev: 0.87589
# Min: 2 Max: 5 Ignored: 0
# ----------------------------------------------
# [ 2, 3)  50   3.81%   3.81% #
# [ 3, 4) 212  16.17%  19.98% ###
# [ 4, 5) 327  24.94%  44.93% #####
# [ 5, 5] 722  55.07% 100.00% ##########
#
# Number of training obs by leaf:
# Count: 1311 Average: 89.1304 StdDev: 286.978
# Min: 5 Max: 1297 Ignored: 0
# ----------------------------------------------
# [    5,   69) 1197  91.30%  91.30% ##########
# [   69,  134)   20   1.53%  92.83%
# [  134,  198)    5   0.38%  93.21%
# [  198,  263)    3   0.23%  93.44%
# [  263,  328)    1   0.08%  93.52%
# [  328,  392)    1   0.08%  93.59%
# [  392,  457)    2   0.15%  93.75%
# [  457,  522)    0   0.00%  93.75%
# [  522,  586)    0   0.00%  93.75%
# [  586,  651)    0   0.00%  93.75%
# [  651,  716)    0   0.00%  93.75%
# [  716,  780)    0   0.00%  93.75%
# [  780,  845)    0   0.00%  93.75%
# [  845,  910)    3   0.23%  93.97%
# [  910,  974)    1   0.08%  94.05%
# [  974, 1039)    3   0.23%  94.28%
# [ 1039, 1104)    4   0.31%  94.58%
# [ 1104, 1168)    4   0.31%  94.89%
# [ 1168, 1233)   30   2.29%  97.18%
# [ 1233, 1297]   37   2.82% 100.00%
#
# Attribute in nodes:
# 	270 : HighGrayLevelEmphasis [NUMERICAL]
# 	221 : DependenceEntropy [NUMERICAL]
# 	175 : LargeDependenceLowGrayLevelEmphasis [NUMERICAL]
# 	122 : GrayLevelNonUniformity [NUMERICAL]
# 	107 : SmallDependenceHighGrayLevelEmphasis [NUMERICAL]
# 	97 : SmallDependenceLowGrayLevelEmphasis [NUMERICAL]
# 	65 : DependenceVariance [NUMERICAL]
# 	58 : LowGrayLevelEmphasis [NUMERICAL]
# 	34 : LargeDependenceHighGrayLevelEmphasis [NUMERICAL]
# 	22 : SmallDependenceEmphasis [NUMERICAL]
# 	18 : DependenceNonUniformityNormalized [NUMERICAL]
# 	18 : DependenceNonUniformity [NUMERICAL]
# 	12 : LargeDependenceEmphasis [NUMERICAL]
# 	10 : GrayLevelVariance [NUMERICAL]
#
# Attribute in nodes with depth <= 0:
# 	82 : HighGrayLevelEmphasis [NUMERICAL]
#
# Attribute in nodes with depth <= 1:
# 	121 : HighGrayLevelEmphasis [NUMERICAL]
# 	60 : GrayLevelNonUniformity [NUMERICAL]
# 	33 : DependenceEntropy [NUMERICAL]
# 	11 : LargeDependenceLowGrayLevelEmphasis [NUMERICAL]
# 	10 : SmallDependenceHighGrayLevelEmphasis [NUMERICAL]
# 	6 : LowGrayLevelEmphasis [NUMERICAL]
# 	4 : LargeDependenceHighGrayLevelEmphasis [NUMERICAL]
# 	1 : SmallDependenceLowGrayLevelEmphasis [NUMERICAL]
#
# Attribute in nodes with depth <= 2:
# 	149 : HighGrayLevelEmphasis [NUMERICAL]
# 	83 : DependenceEntropy [NUMERICAL]
# 	80 : GrayLevelNonUniformity [NUMERICAL]
# 	78 : LargeDependenceLowGrayLevelEmphasis [NUMERICAL]
# 	42 : SmallDependenceLowGrayLevelEmphasis [NUMERICAL]
# 	23 : SmallDependenceHighGrayLevelEmphasis [NUMERICAL]
# 	21 : LowGrayLevelEmphasis [NUMERICAL]
# 	12 : LargeDependenceHighGrayLevelEmphasis [NUMERICAL]
# 	11 : DependenceVariance [NUMERICAL]
# 	6 : LargeDependenceEmphasis [NUMERICAL]
# 	6 : DependenceNonUniformity [NUMERICAL]
# 	5 : SmallDependenceEmphasis [NUMERICAL]
# 	5 : DependenceNonUniformityNormalized [NUMERICAL]
# 	3 : GrayLevelVariance [NUMERICAL]
#
# Attribute in nodes with depth <= 3:
# 	202 : HighGrayLevelEmphasis [NUMERICAL]
# 	160 : DependenceEntropy [NUMERICAL]
# 	131 : LargeDependenceLowGrayLevelEmphasis [NUMERICAL]
# 	97 : GrayLevelNonUniformity [NUMERICAL]
# 	72 : SmallDependenceHighGrayLevelEmphasis [NUMERICAL]
# 	70 : SmallDependenceLowGrayLevelEmphasis [NUMERICAL]
# 	33 : DependenceVariance [NUMERICAL]
# 	30 : LowGrayLevelEmphasis [NUMERICAL]
# 	22 : LargeDependenceHighGrayLevelEmphasis [NUMERICAL]
# 	12 : DependenceNonUniformityNormalized [NUMERICAL]
# 	11 : SmallDependenceEmphasis [NUMERICAL]
# 	11 : DependenceNonUniformity [NUMERICAL]
# 	9 : LargeDependenceEmphasis [NUMERICAL]
# 	8 : GrayLevelVariance [NUMERICAL]
#
# Attribute in nodes with depth <= 5:
# 	270 : HighGrayLevelEmphasis [NUMERICAL]
# 	221 : DependenceEntropy [NUMERICAL]
# 	175 : LargeDependenceLowGrayLevelEmphasis [NUMERICAL]
# 	122 : GrayLevelNonUniformity [NUMERICAL]
# 	107 : SmallDependenceHighGrayLevelEmphasis [NUMERICAL]
# 	97 : SmallDependenceLowGrayLevelEmphasis [NUMERICAL]
# 	65 : DependenceVariance [NUMERICAL]
# 	58 : LowGrayLevelEmphasis [NUMERICAL]
# 	34 : LargeDependenceHighGrayLevelEmphasis [NUMERICAL]
# 	22 : SmallDependenceEmphasis [NUMERICAL]
# 	18 : DependenceNonUniformityNormalized [NUMERICAL]
# 	18 : DependenceNonUniformity [NUMERICAL]
# 	12 : LargeDependenceEmphasis [NUMERICAL]
# 	10 : GrayLevelVariance [NUMERICAL]
#
# Condition type in nodes:
# 	1229 : HigherCondition
# Condition type in nodes with depth <= 0:
# 	82 : HigherCondition
# Condition type in nodes with depth <= 1:
# 	246 : HigherCondition
# Condition type in nodes with depth <= 2:
# 	524 : HigherCondition
# Condition type in nodes with depth <= 3:
# 	868 : HigherCondition
# Condition type in nodes with depth <= 5:
# 	1229 : HigherCondition
#
# Training logs:
# Number of iteration to final model: 82
# 	Iter:1 train-loss:1.198930 valid-loss:1.204625  train-accuracy:0.995413 valid-accuracy:0.996547
# 	Iter:2 train-loss:1.045656 valid-loss:1.047687  train-accuracy:0.997325 valid-accuracy:1.000000
# 	Iter:3 train-loss:0.917906 valid-loss:0.918029  train-accuracy:0.995413 valid-accuracy:0.996547
# 	Iter:4 train-loss:0.809775 valid-loss:0.807369  train-accuracy:0.997325 valid-accuracy:1.000000
# 	Iter:5 train-loss:0.717521 valid-loss:0.713800  train-accuracy:0.997325 valid-accuracy:1.000000
# 	Iter:6 train-loss:0.637905 valid-loss:0.632844  train-accuracy:0.997325 valid-accuracy:1.000000
# 	Iter:16 train-loss:0.216327 valid-loss:0.213231  train-accuracy:0.998471 valid-accuracy:1.000000
# 	Iter:26 train-loss:0.080578 valid-loss:0.095907  train-accuracy:0.998853 valid-accuracy:1.000000
# 	Iter:36 train-loss:0.031286 valid-loss:0.055216  train-accuracy:1.000000 valid-accuracy:1.000000
# 	Iter:46 train-loss:0.012735 valid-loss:0.033867  train-accuracy:1.000000 valid-accuracy:1.000000
# 	Iter:56 train-loss:0.005640 valid-loss:0.028082  train-accuracy:1.000000 valid-accuracy:1.000000
# 	Iter:66 train-loss:0.002306 valid-loss:0.018479  train-accuracy:1.000000 valid-accuracy:1.000000
# 	Iter:76 train-loss:0.000963 valid-loss:0.017288  train-accuracy:1.000000 valid-accuracy:1.000000
# 	Iter:86 train-loss:0.000426 valid-loss:0.019377  train-accuracy:1.000000 valid-accuracy:1.000000
# 	Iter:96 train-loss:0.000201 valid-loss:0.021708  train-accuracy:1.000000 valid-accuracy:1.000000
# 	Iter:106 train-loss:0.000095 valid-loss:0.020177  train-accuracy:1.000000 valid-accuracy:1.000000

# %%
# Model features
model.make_inspector().features()
# Out:
# ["DependenceEntropy" (1; #0),
#  "DependenceNonUniformity" (1; #1),
#  "DependenceNonUniformityNormalized" (1; #2),
#  "DependenceVariance" (1; #3),
#  "GrayLevelNonUniformity" (1; #4),
#  "GrayLevelVariance" (1; #5),
#  "HighGrayLevelEmphasis" (1; #6),
#  "LargeDependenceEmphasis" (1; #7),
#  "LargeDependenceHighGrayLevelEmphasis" (1; #8),
#  "LargeDependenceLowGrayLevelEmphasis" (1; #9),
#  "LowGrayLevelEmphasis" (1; #10),
#  "SmallDependenceEmphasis" (1; #11),
#  "SmallDependenceHighGrayLevelEmphasis" (1; #12),
#  "SmallDependenceLowGrayLevelEmphasis" (1; #13)]

# %%
# Feature importance
model.make_inspector().variable_importances()
# Out:
# {'INV_MEAN_MIN_DEPTH': [("HighGrayLevelEmphasis" (1; #6), 1.0),
#   ("GrayLevelNonUniformity" (1; #4), 0.260893180358047),
#   ("DependenceEntropy" (1; #0), 0.25534628433333995),
#   ("LargeDependenceLowGrayLevelEmphasis" (1; #9), 0.22954944100685434),
#   ("SmallDependenceLowGrayLevelEmphasis" (1; #13), 0.20902284025681941),
#   ("SmallDependenceHighGrayLevelEmphasis" (1; #12), 0.20781379515543882),
#   ("LowGrayLevelEmphasis" (1; #10), 0.19948419753350688),
#   ("LargeDependenceHighGrayLevelEmphasis" (1; #8), 0.19812975893111948),
#   ("DependenceVariance" (1; #3), 0.19634272824524604),
#   ("SmallDependenceEmphasis" (1; #11), 0.1920616440277067),
#   ("DependenceNonUniformity" (1; #1), 0.1913650651401915),
#   ("DependenceNonUniformityNormalized" (1; #2), 0.1913422437389933),
#   ("LargeDependenceEmphasis" (1; #7), 0.19066412392683002),
#   ("GrayLevelVariance" (1; #5), 0.18992703015786314)],
#  'SUM_SCORE': [("HighGrayLevelEmphasis" (1; #6), 1580.2663746087958),
#   ("GrayLevelNonUniformity" (1; #4), 170.23928075449496),
#   ("LargeDependenceLowGrayLevelEmphasis" (1; #9), 65.37367370340425),
#   ("DependenceVariance" (1; #3), 33.47931540313194),
#   ("SmallDependenceHighGrayLevelEmphasis" (1; #12), 9.88163903392569),
#   ("SmallDependenceLowGrayLevelEmphasis" (1; #13), 6.359155956770791),
#   ("LargeDependenceHighGrayLevelEmphasis" (1; #8), 3.614444707874545),
#   ("DependenceEntropy" (1; #0), 2.852714236402951),
#   ("LargeDependenceEmphasis" (1; #7), 2.548840449720944),
#   ("DependenceNonUniformity" (1; #1), 2.3241153130642505),
#   ("DependenceNonUniformityNormalized" (1; #2), 0.759161819054374),
#   ("LowGrayLevelEmphasis" (1; #10), 0.23703568278291337),
#   ("GrayLevelVariance" (1; #5), 0.059634893392122655),
#   ("SmallDependenceEmphasis" (1; #11), 0.017282242005848325)],
#  'NUM_AS_ROOT': [("HighGrayLevelEmphasis" (1; #6), 82.0)],
#  'NUM_NODES': [("HighGrayLevelEmphasis" (1; #6), 270.0),
#   ("DependenceEntropy" (1; #0), 221.0),
#   ("LargeDependenceLowGrayLevelEmphasis" (1; #9), 175.0),
#   ("GrayLevelNonUniformity" (1; #4), 122.0),
#   ("SmallDependenceHighGrayLevelEmphasis" (1; #12), 107.0),
#   ("SmallDependenceLowGrayLevelEmphasis" (1; #13), 97.0),
#   ("DependenceVariance" (1; #3), 65.0),
#   ("LowGrayLevelEmphasis" (1; #10), 58.0),
#   ("LargeDependenceHighGrayLevelEmphasis" (1; #8), 34.0),
#   ("SmallDependenceEmphasis" (1; #11), 22.0),
#   ("DependenceNonUniformity" (1; #1), 18.0),
#   ("DependenceNonUniformityNormalized" (1; #2), 18.0),
#   ("LargeDependenceEmphasis" (1; #7), 12.0),
#   ("GrayLevelVariance" (1; #5), 10.0)]}

# %%
# Model self evaluation
model.make_inspector().evaluation()
# Out:
# Evaluation(num_examples=None, accuracy=1.0, loss=0.015449459664523602, rmse=None, ndcg=None, aucs=None, auuc=None, qini=None)

# %%
logs = model.make_inspector().training_logs()

plt.figure(figsize=(12, 4))
plt.subplot(1, 2, 1)
plt.plot([log.num_trees for log in logs], [log.evaluation.accuracy for log in logs])
plt.xlabel("Number of trees")
plt.ylabel("Accuracy (out-of-bag)")
plt.subplot(1, 2, 2)
plt.plot([log.num_trees for log in logs], [log.evaluation.loss for log in logs])
plt.xlabel("Number of trees")
plt.ylabel("Logloss (out-of-bag)")
plt.show()

# %% [markdown]
# Calculate the score of our hold-out validation dataset

# %%
predictions = model.predict(val_ds)
y_true      = validation_data["label"]

from sklearn.metrics import roc_auc_score
ROC_AUC = roc_auc_score(y_true, predictions)
print("The ROC AUC score is %.5f" % ROC_AUC )
# Out:
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 62ms/step
# The ROC AUC score is 0.99127

# %%
# Compute binary classification metrics with sklearn
import numpy as np
from sklearn.metrics import (
    accuracy_score,
    precision_score,
    recall_score,
    f1_score,
    roc_auc_score,
    average_precision_score,
    confusion_matrix,
    classification_report,
    matthews_corrcoef,
    log_loss,
    brier_score_loss,
)

# Get predictions (probabilities or class labels)
preds = model.predict(test_ds)
# If model outputs probabilities, convert to labels by threshold 0.5
if preds.ndim == 2:
    # For TFDF classification, preds may be class probabilities with shape (N, 2)
    if preds.shape[1] == 2:
        pos_probs = preds[:, 1]
    else:
        # If single-probability column (positive class)
        pos_probs = preds[:, -1]
    y_pred = (pos_probs >= 0.5).astype(int)
else:
    # Already class labels
    y_pred = preds.astype(int)
    pos_probs = None

# Ground truth labels (must be 0/1 integers)
y_true = test_data["label"].astype(int).to_numpy()

# Core metrics
metrics = {}
metrics["accuracy"] = accuracy_score(y_true, y_pred)
metrics["precision"] = precision_score(y_true, y_pred, zero_division=0)
metrics["recall"] = recall_score(y_true, y_pred, zero_division=0)
metrics["f1"] = f1_score(y_true, y_pred, zero_division=0)
metrics["mcc"] = matthews_corrcoef(y_true, y_pred)

# Probabilistic metrics (only if we have probabilities)
if pos_probs is not None:
    metrics["roc_auc"] = roc_auc_score(y_true, pos_probs)
    metrics["pr_auc"] = average_precision_score(y_true, pos_probs)
    metrics["log_loss"] = log_loss(y_true, pos_probs, labels=[0,1])
    metrics["brier_score"] = brier_score_loss(y_true, pos_probs)

# Confusion matrix and detailed report
cm = confusion_matrix(y_true, y_pred, labels=[0,1])
report = classification_report(y_true, y_pred, digits=4)

print("Sklearn binary metrics:")
for k, v in metrics.items():
    print(f"{k}: {v:.4f}")
print("\nConfusion matrix:\n", cm)
print("\nClassification report:\n", report)
# Out:
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 67ms/step
# Sklearn binary metrics:
# accuracy: 0.9955
# precision: 1.0000
# recall: 0.9231
# f1: 0.9600
# mcc: 0.9585
# roc_auc: 0.9982
# pr_auc: 0.9833
# log_loss: 0.0230
# brier_score: 0.0034
#
# Confusion matrix:
#  [[418   0]
#  [  2  24]]
#
# Classification report:
#                precision    recall  f1-score   support
#
#            0     0.9952    1.0000    0.9976       418
#            1     1.0000    0.9231    0.9600        26
#
#     accuracy                         0.9955       444
#    macro avg     0.9976    0.9615    0.9788       444
# weighted avg     0.9955    0.9955    0.9954       444
