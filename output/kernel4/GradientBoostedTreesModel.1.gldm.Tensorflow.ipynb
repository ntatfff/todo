# %%
# Import packages and modules
import numpy  as np
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow_decision_forests as tfdf

from sklearn.model_selection import train_test_split
# Out:
# 2026-08-10 17:11:31.114051: I tensorflow/core/util/port.cc:113] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2026-08-10 17:11:31.517121: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2026-08-10 17:11:36.130122: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
# Check the version of TensorFlow Decision Forests
print("Found TensorFlow Decision Forests v" + tfdf.__version__)
# Out:
# Found TensorFlow Decision Forests v1.9.1

# %%
datasetPath = 'dataset/firstorder/kernel5-radius5/dataset.csv'

# %%
# Parameters
datasetPath = "dataset/gldm/kernel4-radius4/dataset.1p.csv"

# %%
# train/validation/test = 70/10/20
dataset = pd.read_csv(datasetPath)

train_data, temp_data = train_test_split(dataset, test_size=0.3, random_state=42)
validation_data, test_data = train_test_split(temp_data, test_size=2/3, random_state=42)

# %%
from sklearn.utils.class_weight import compute_class_weight

# tinh class weight tren tap train
classes = np.array([0, 1])
weights = compute_class_weight(class_weight="balanced", classes=classes, y=train_data["label"])
class_weight = {0: weights[0], 1: weights[1]}

# gan sample_weight cho tung dong
train_data["sample_weight"] = train_data["label"].map(class_weight)
validation_data["sample_weight"] = validation_data["label"].map(class_weight)
test_data["sample_weight"] = test_data["label"].map(class_weight)

# Convert the dataset into a TensorFlow dataset.
train_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    train_data, label="label", weight="sample_weight"
)         
val_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    validation_data, label="label", weight="sample_weight"
)
test_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    test_data, label="label", weight="sample_weight"
)
# Out:
# 2026-08-10 17:11:50.999074: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:984] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2026-08-10 17:11:51.000287: W tensorflow/core/common_runtime/gpu/gpu_device.cc:2251] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...

# %%
import keras

# %%
# %%time

# Train a Gradient Boosted Trees model.
model = tfdf.keras.GradientBoostedTreesModel()

# Add evaluation metrics
model.compile(
    metrics=["accuracy"]
)
model.fit(x=train_ds)

# # Train a Gradient Boosted Trees model.
# model = tfdf.keras.GradientBoostedTreesModel(num_trees=1500)
# model.fit(train_ds)
# Out:
# Use /tmp/tmplyed_pcy as temporary training directory
# Reading training dataset...
# [WARNING 26-08-10 17:11:51.1628 UTC gradient_boosted_trees.cc:1840] "goss_alpha" set but "sampling_method" not equal to "GOSS".
# [WARNING 26-08-10 17:11:51.1631 UTC gradient_boosted_trees.cc:1851] "goss_beta" set but "sampling_method" not equal to "GOSS".
# [WARNING 26-08-10 17:11:51.1631 UTC gradient_boosted_trees.cc:1865] "selective_gradient_boosting_ratio" set but "sampling_method" not equal to "SELGB".
# Training dataset read in 0:00:02.540744. Found 1542 examples.
# Training model...
# Model trained in 0:00:01.582256
# Compiling model...
# [INFO 26-08-10 17:11:55.3044 UTC kernel.cc:1233] Loading model from path /tmp/tmplyed_pcy/model/ with prefix bd010bd7d99149e6
# [INFO 26-08-10 17:11:55.3118 UTC quick_scorer_extended.cc:911] The binary was compiled without AVX2 support, but your CPU supports it. Enable it for faster model inference.
# [INFO 26-08-10 17:11:55.3122 UTC abstract_model.cc:1362] Engine "GradientBoostedTreesQuickScorerExtended" built
# [INFO 26-08-10 17:11:55.3122 UTC kernel.cc:1061] Use fast generic engine
# Model compiled.
# CPU times: user 8.14 s, sys: 2.05 s, total: 10.2 s
# Wall time: 7.19 s

# %%
# Evaluate the model
evaluate = model.evaluate(val_ds, return_dict=True)
print()

for name, value in evaluate.items():
    print(f"{name}: {value:.4f}")
# Out:
# WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 1/1 [==============================] - ETA: 0s - loss: 0.0000e+00 - accuracy: 0.9955
# 1/1 [==============================] - 3s 3s/step - loss: 0.0000e+00 - accuracy: 0.9955
# loss: 0.0000
# accuracy: 0.9955

# %%
# Model Summary
model.summary()
# Out:
# Model: "gradient_boosted_trees_model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
# =================================================================
# Total params: 1 (1.00 Byte)
# Trainable params: 0 (0.00 Byte)
# Non-trainable params: 1 (1.00 Byte)
# _________________________________________________________________
# Type: "GRADIENT_BOOSTED_TREES"
# Task: CLASSIFICATION
# Label: "__LABEL"
#
# Input Features (32):
# 	10Percentile
# 	90Percentile
# 	DependenceEntropy
# 	DependenceNonUniformity
# 	DependenceNonUniformityNormalized
# 	DependenceVariance
# 	Energy
# 	Entropy
# 	GrayLevelNonUniformity
# 	GrayLevelVariance
# 	HighGrayLevelEmphasis
# 	InterquartileRange
# 	Kurtosis
# 	LargeDependenceEmphasis
# 	LargeDependenceHighGrayLevelEmphasis
# 	LargeDependenceLowGrayLevelEmphasis
# 	LowGrayLevelEmphasis
# 	Maximum
# 	Mean
# 	MeanAbsoluteDeviation
# 	Median
# 	Minimum
# 	Range
# 	RobustMeanAbsoluteDeviation
# 	RootMeanSquared
# 	Skewness
# 	SmallDependenceEmphasis
# 	SmallDependenceHighGrayLevelEmphasis
# 	SmallDependenceLowGrayLevelEmphasis
# 	TotalEnergy
# 	Uniformity
# 	Variance
#
# Trained with weights
#
# Variable Importance: INV_MEAN_MIN_DEPTH:
#     1.  "LargeDependenceLowGrayLevelEmphasis"  0.300680 ################
#     2.    "DependenceNonUniformityNormalized"  0.283925 #############
#     3.              "DependenceNonUniformity"  0.281972 ############
#     4.                                 "Mean"  0.280344 ############
#     5.                   "DependenceVariance"  0.241238 #####
#     6.              "LargeDependenceEmphasis"  0.235538 ####
#     7.  "SmallDependenceLowGrayLevelEmphasis"  0.235474 ####
#     8.              "SmallDependenceEmphasis"  0.228179 ###
#     9. "SmallDependenceHighGrayLevelEmphasis"  0.226545 ##
#    10.                               "Median"  0.224693 ##
#    11.                 "LowGrayLevelEmphasis"  0.220736 #
#    12.                               "Energy"  0.217232 #
#    13.                          "TotalEnergy"  0.216290
#    14.                      "RootMeanSquared"  0.215800
#    15.               "GrayLevelNonUniformity"  0.214937
#    16.                    "GrayLevelVariance"  0.213469
#    17. "LargeDependenceHighGrayLevelEmphasis"  0.213044
#    18.                             "Skewness"  0.212976
#    19.                    "DependenceEntropy"  0.212893
#    20.                "MeanAbsoluteDeviation"  0.212857
#    21.                         "10Percentile"  0.212518
#    22.                   "InterquartileRange"  0.212044
#    23.                              "Entropy"  0.211938
#    24.                "HighGrayLevelEmphasis"  0.211908
#    25.                             "Kurtosis"  0.211876
#    26.                              "Maximum"  0.211762
#    27.                           "Uniformity"  0.211676
#    28.                              "Minimum"  0.211540
#    29.                             "Variance"  0.211444
#    30.          "RobustMeanAbsoluteDeviation"  0.211264
#    31.                                "Range"  0.211108
#    32.                         "90Percentile"  0.211101
#
# Variable Importance: NUM_AS_ROOT:
#     1.  "LargeDependenceLowGrayLevelEmphasis" 117.000000 ################
#     2.    "DependenceNonUniformityNormalized" 92.000000 ############
#     3.              "DependenceNonUniformity" 90.000000 ############
#     4. "LargeDependenceHighGrayLevelEmphasis"  1.000000
#
# Variable Importance: NUM_NODES:
#     1.                   "DependenceVariance" 321.000000 ################
#     2. "SmallDependenceHighGrayLevelEmphasis" 298.000000 ##############
#     3.  "SmallDependenceLowGrayLevelEmphasis" 277.000000 #############
#     4.  "LargeDependenceLowGrayLevelEmphasis" 261.000000 ############
#     5.              "SmallDependenceEmphasis" 257.000000 ############
#     6.                               "Median" 229.000000 ###########
#     7.                                 "Mean" 222.000000 ##########
#     8.              "LargeDependenceEmphasis" 157.000000 #######
#     9.    "DependenceNonUniformityNormalized" 142.000000 ######
#    10.               "GrayLevelNonUniformity" 133.000000 ######
#    11.              "DependenceNonUniformity" 127.000000 #####
#    12.                             "Skewness" 94.000000 ####
#    13.                    "GrayLevelVariance" 90.000000 ####
#    14.                               "Energy" 85.000000 ###
#    15.                      "RootMeanSquared" 77.000000 ###
#    16.                          "TotalEnergy" 77.000000 ###
#    17.                    "DependenceEntropy" 72.000000 ###
#    18.                 "LowGrayLevelEmphasis" 56.000000 ##
#    19. "LargeDependenceHighGrayLevelEmphasis" 52.000000 ##
#    20.                "MeanAbsoluteDeviation" 48.000000 #
#    21.                              "Entropy" 44.000000 #
#    22.                         "10Percentile" 43.000000 #
#    23.                              "Maximum" 42.000000 #
#    24.                   "InterquartileRange" 40.000000 #
#    25.                "HighGrayLevelEmphasis" 38.000000 #
#    26.                             "Kurtosis" 33.000000 #
#    27.                           "Uniformity" 33.000000 #
#    28.                              "Minimum" 22.000000
#    29.                             "Variance" 22.000000
#    30.          "RobustMeanAbsoluteDeviation" 14.000000
#    31.                         "90Percentile" 12.000000
#    32.                                "Range" 12.000000
#
# Variable Importance: SUM_SCORE:
#     1.  "LargeDependenceLowGrayLevelEmphasis" 1503.735811 ################
#     2.                   "DependenceVariance" 320.847379 ###
#     3.                 "LowGrayLevelEmphasis" 80.574263
#     4.              "LargeDependenceEmphasis"  0.000001
#     5.              "DependenceNonUniformity"  0.000001
#     6.    "DependenceNonUniformityNormalized"  0.000001
#     7.  "SmallDependenceLowGrayLevelEmphasis"  0.000001
#     8.              "SmallDependenceEmphasis"  0.000001
#     9.                                 "Mean"  0.000000
#    10. "SmallDependenceHighGrayLevelEmphasis"  0.000000
#    11.                               "Median"  0.000000
#    12.               "GrayLevelNonUniformity"  0.000000
#    13.                               "Energy"  0.000000
#    14. "LargeDependenceHighGrayLevelEmphasis"  0.000000
#    15.                          "TotalEnergy"  0.000000
#    16.                      "RootMeanSquared"  0.000000
#    17.                    "GrayLevelVariance"  0.000000
#    18.                         "10Percentile"  0.000000
#    19.                    "DependenceEntropy"  0.000000
#    20.                              "Entropy"  0.000000
#    21.                   "InterquartileRange"  0.000000
#    22.                             "Kurtosis"  0.000000
#    23.                "MeanAbsoluteDeviation"  0.000000
#    24.                           "Uniformity"  0.000000
#    25.                             "Variance"  0.000000
#    26.                              "Minimum"  0.000000
#    27.                             "Skewness"  0.000000
#    28.                                "Range"  0.000000
#    29.          "RobustMeanAbsoluteDeviation"  0.000000
#    30.                "HighGrayLevelEmphasis"  0.000000
#    31.                              "Maximum"  0.000000
#    32.                         "90Percentile"  0.000000
#
#
#
# Loss: BINOMIAL_LOG_LIKELIHOOD
# Validation loss value: 9.29887e-07
# Number of trees per iteration: 1
# Node format: NOT_SET
# Number of trees: 300
# Total number of nodes: 7160
#
# Number of nodes by tree:
# Count: 300 Average: 23.8667 StdDev: 6.53979
# Min: 7 Max: 37 Ignored: 0
# ----------------------------------------------
# [  7,  8)   1   0.33%   0.33%
# [  8, 10)   3   1.00%   1.33%
# [ 10, 11)   0   0.00%   1.33%
# [ 11, 13)   7   2.33%   3.67%
# [ 13, 14)  20   6.67%  10.33% #
# [ 14, 16)  21   7.00%  17.33% #
# [ 16, 17)   0   0.00%  17.33%
# [ 17, 19)  13   4.33%  21.67% #
# [ 19, 20)   8   2.67%  24.33%
# [ 20, 22)   4   1.33%  25.67%
# [ 22, 24)   0   0.00%  25.67%
# [ 24, 25)   0   0.00%  25.67%
# [ 25, 27) 171  57.00%  82.67% ##########
# [ 27, 28)   9   3.00%  85.67% #
# [ 28, 30)   6   2.00%  87.67%
# [ 30, 31)   0   0.00%  87.67%
# [ 31, 33)   3   1.00%  88.67%
# [ 33, 34)   3   1.00%  89.67%
# [ 34, 36)   7   2.33%  92.00%
# [ 36, 37]  24   8.00% 100.00% #
#
# Depth by leafs:
# Count: 3730 Average: 3.86113 StdDev: 0.808809
# Min: 1 Max: 5 Ignored: 0
# ----------------------------------------------
# [ 1, 2)    2   0.05%   0.05%
# [ 2, 3)   97   2.60%   2.65% #
# [ 3, 4) 1212  32.49%  35.15% ########
# [ 4, 5) 1525  40.88%  76.03% ##########
# [ 5, 5]  894  23.97% 100.00% ######
#
# Number of training obs by leaf:
# Count: 3730 Average: 113.887 StdDev: 260.512
# Min: 5 Max: 1204 Ignored: 0
# ----------------------------------------------
# [    5,   65) 2907  77.94%  77.94% ##########
# [   65,  125)   82   2.20%  80.13%
# [  125,  185)   68   1.82%  81.96%
# [  185,  245)  200   5.36%  87.32% #
# [  245,  305)   51   1.37%  88.69%
# [  305,  365)   65   1.74%  90.43%
# [  365,  425)    3   0.08%  90.51%
# [  425,  485)    0   0.00%  90.51%
# [  485,  545)   40   1.07%  91.58%
# [  545,  605)   18   0.48%  92.06%
# [  605,  665)   12   0.32%  92.39%
# [  665,  725)   23   0.62%  93.00%
# [  725,  785)   63   1.69%  94.69%
# [  785,  845)   71   1.90%  96.60%
# [  845,  905)    0   0.00%  96.60%
# [  905,  965)    0   0.00%  96.60%
# [  965, 1025)    7   0.19%  96.78%
# [ 1025, 1085)    0   0.00%  96.78%
# [ 1085, 1145)   49   1.31%  98.10%
# [ 1145, 1204]   71   1.90% 100.00%
#
# Attribute in nodes:
# 	321 : DependenceVariance [NUMERICAL]
# 	298 : SmallDependenceHighGrayLevelEmphasis [NUMERICAL]
# 	277 : SmallDependenceLowGrayLevelEmphasis [NUMERICAL]
# 	261 : LargeDependenceLowGrayLevelEmphasis [NUMERICAL]
# 	257 : SmallDependenceEmphasis [NUMERICAL]
# 	229 : Median [NUMERICAL]
# 	222 : Mean [NUMERICAL]
# 	157 : LargeDependenceEmphasis [NUMERICAL]
# 	142 : DependenceNonUniformityNormalized [NUMERICAL]
# 	133 : GrayLevelNonUniformity [NUMERICAL]
# 	127 : DependenceNonUniformity [NUMERICAL]
# 	94 : Skewness [NUMERICAL]
# 	90 : GrayLevelVariance [NUMERICAL]
# 	85 : Energy [NUMERICAL]
# 	77 : TotalEnergy [NUMERICAL]
# 	77 : RootMeanSquared [NUMERICAL]
# 	72 : DependenceEntropy [NUMERICAL]
# 	56 : LowGrayLevelEmphasis [NUMERICAL]
# 	52 : LargeDependenceHighGrayLevelEmphasis [NUMERICAL]
# 	48 : MeanAbsoluteDeviation [NUMERICAL]
# 	44 : Entropy [NUMERICAL]
# 	43 : 10Percentile [NUMERICAL]
# 	42 : Maximum [NUMERICAL]
# 	40 : InterquartileRange [NUMERICAL]
# 	38 : HighGrayLevelEmphasis [NUMERICAL]
# 	33 : Uniformity [NUMERICAL]
# 	33 : Kurtosis [NUMERICAL]
# 	22 : Variance [NUMERICAL]
# 	22 : Minimum [NUMERICAL]
# 	14 : RobustMeanAbsoluteDeviation [NUMERICAL]
# 	12 : Range [NUMERICAL]
# 	12 : 90Percentile [NUMERICAL]
#
# Attribute in nodes with depth <= 0:
# 	117 : LargeDependenceLowGrayLevelEmphasis [NUMERICAL]
# 	92 : DependenceNonUniformityNormalized [NUMERICAL]
# 	90 : DependenceNonUniformity [NUMERICAL]
# 	1 : LargeDependenceHighGrayLevelEmphasis [NUMERICAL]
#
# Attribute in nodes with depth <= 1:
# 	177 : Mean [NUMERICAL]
# 	166 : LargeDependenceLowGrayLevelEmphasis [NUMERICAL]
# 	143 : DependenceVariance [NUMERICAL]
# 	137 : LargeDependenceEmphasis [NUMERICAL]
# 	96 : DependenceNonUniformity [NUMERICAL]
# 	95 : DependenceNonUniformityNormalized [NUMERICAL]
# 	39 : LowGrayLevelEmphasis [NUMERICAL]
# 	8 : LargeDependenceHighGrayLevelEmphasis [NUMERICAL]
# 	6 : SmallDependenceLowGrayLevelEmphasis [NUMERICAL]
# 	6 : SmallDependenceHighGrayLevelEmphasis [NUMERICAL]
# 	5 : SmallDependenceEmphasis [NUMERICAL]
# 	5 : DependenceEntropy [NUMERICAL]
# 	4 : GrayLevelVariance [NUMERICAL]
# 	4 : Energy [NUMERICAL]
# 	3 : HighGrayLevelEmphasis [NUMERICAL]
# 	3 : GrayLevelNonUniformity [NUMERICAL]
# 	1 : TotalEnergy [NUMERICAL]
#
# Attribute in nodes with depth <= 2:
# 	255 : SmallDependenceHighGrayLevelEmphasis [NUMERICAL]
# 	208 : SmallDependenceLowGrayLevelEmphasis [NUMERICAL]
# 	186 : Mean [NUMERICAL]
# 	175 : LargeDependenceLowGrayLevelEmphasis [NUMERICAL]
# 	156 : DependenceVariance [NUMERICAL]
# 	147 : LargeDependenceEmphasis [NUMERICAL]
# 	110 : DependenceNonUniformityNormalized [NUMERICAL]
# 	102 : DependenceNonUniformity [NUMERICAL]
# 	95 : Median [NUMERICAL]
# 	82 : GrayLevelVariance [NUMERICAL]
# 	79 : GrayLevelNonUniformity [NUMERICAL]
# 	69 : DependenceEntropy [NUMERICAL]
# 	61 : SmallDependenceEmphasis [NUMERICAL]
# 	48 : LowGrayLevelEmphasis [NUMERICAL]
# 	46 : TotalEnergy [NUMERICAL]
# 	45 : Energy [NUMERICAL]
# 	42 : RootMeanSquared [NUMERICAL]
# 	14 : LargeDependenceHighGrayLevelEmphasis [NUMERICAL]
# 	9 : HighGrayLevelEmphasis [NUMERICAL]
# 	8 : Kurtosis [NUMERICAL]
# 	8 : InterquartileRange [NUMERICAL]
# 	8 : Entropy [NUMERICAL]
# 	7 : Uniformity [NUMERICAL]
# 	7 : MeanAbsoluteDeviation [NUMERICAL]
# 	6 : Variance [NUMERICAL]
# 	6 : Minimum [NUMERICAL]
# 	4 : RobustMeanAbsoluteDeviation [NUMERICAL]
# 	4 : 10Percentile [NUMERICAL]
# 	3 : Skewness [NUMERICAL]
# 	3 : Maximum [NUMERICAL]
# 	2 : Range [NUMERICAL]
# 	2 : 90Percentile [NUMERICAL]
#
# Attribute in nodes with depth <= 3:
# 	295 : SmallDependenceHighGrayLevelEmphasis [NUMERICAL]
# 	288 : DependenceVariance [NUMERICAL]
# 	272 : SmallDependenceLowGrayLevelEmphasis [NUMERICAL]
# 	250 : SmallDependenceEmphasis [NUMERICAL]
# 	226 : Median [NUMERICAL]
# 	216 : Mean [NUMERICAL]
# 	179 : LargeDependenceLowGrayLevelEmphasis [NUMERICAL]
# 	150 : LargeDependenceEmphasis [NUMERICAL]
# 	113 : DependenceNonUniformityNormalized [NUMERICAL]
# 	109 : GrayLevelNonUniformity [NUMERICAL]
# 	105 : DependenceNonUniformity [NUMERICAL]
# 	86 : GrayLevelVariance [NUMERICAL]
# 	73 : Energy [NUMERICAL]
# 	71 : TotalEnergy [NUMERICAL]
# 	71 : RootMeanSquared [NUMERICAL]
# 	71 : DependenceEntropy [NUMERICAL]
# 	56 : Skewness [NUMERICAL]
# 	56 : LowGrayLevelEmphasis [NUMERICAL]
# 	43 : LargeDependenceHighGrayLevelEmphasis [NUMERICAL]
# 	37 : Maximum [NUMERICAL]
# 	36 : HighGrayLevelEmphasis [NUMERICAL]
# 	32 : 10Percentile [NUMERICAL]
# 	27 : MeanAbsoluteDeviation [NUMERICAL]
# 	21 : Entropy [NUMERICAL]
# 	17 : Kurtosis [NUMERICAL]
# 	15 : Uniformity [NUMERICAL]
# 	15 : InterquartileRange [NUMERICAL]
# 	14 : Minimum [NUMERICAL]
# 	13 : Variance [NUMERICAL]
# 	12 : RobustMeanAbsoluteDeviation [NUMERICAL]
# 	10 : 90Percentile [NUMERICAL]
# 	4 : Range [NUMERICAL]
#
# Attribute in nodes with depth <= 5:
# 	321 : DependenceVariance [NUMERICAL]
# 	298 : SmallDependenceHighGrayLevelEmphasis [NUMERICAL]
# 	277 : SmallDependenceLowGrayLevelEmphasis [NUMERICAL]
# 	261 : LargeDependenceLowGrayLevelEmphasis [NUMERICAL]
# 	257 : SmallDependenceEmphasis [NUMERICAL]
# 	229 : Median [NUMERICAL]
# 	222 : Mean [NUMERICAL]
# 	157 : LargeDependenceEmphasis [NUMERICAL]
# 	142 : DependenceNonUniformityNormalized [NUMERICAL]
# 	133 : GrayLevelNonUniformity [NUMERICAL]
# 	127 : DependenceNonUniformity [NUMERICAL]
# 	94 : Skewness [NUMERICAL]
# 	90 : GrayLevelVariance [NUMERICAL]
# 	85 : Energy [NUMERICAL]
# 	77 : TotalEnergy [NUMERICAL]
# 	77 : RootMeanSquared [NUMERICAL]
# 	72 : DependenceEntropy [NUMERICAL]
# 	56 : LowGrayLevelEmphasis [NUMERICAL]
# 	52 : LargeDependenceHighGrayLevelEmphasis [NUMERICAL]
# 	48 : MeanAbsoluteDeviation [NUMERICAL]
# 	44 : Entropy [NUMERICAL]
# 	43 : 10Percentile [NUMERICAL]
# 	42 : Maximum [NUMERICAL]
# 	40 : InterquartileRange [NUMERICAL]
# 	38 : HighGrayLevelEmphasis [NUMERICAL]
# 	33 : Uniformity [NUMERICAL]
# 	33 : Kurtosis [NUMERICAL]
# 	22 : Variance [NUMERICAL]
# 	22 : Minimum [NUMERICAL]
# 	14 : RobustMeanAbsoluteDeviation [NUMERICAL]
# 	12 : Range [NUMERICAL]
# 	12 : 90Percentile [NUMERICAL]
#
# Condition type in nodes:
# 	3430 : HigherCondition
# Condition type in nodes with depth <= 0:
# 	300 : HigherCondition
# Condition type in nodes with depth <= 1:
# 	898 : HigherCondition
# Condition type in nodes with depth <= 2:
# 	1997 : HigherCondition
# Condition type in nodes with depth <= 3:
# 	2983 : HigherCondition
# Condition type in nodes with depth <= 5:
# 	3430 : HigherCondition
#
# Training logs:
# Number of iteration to final model: 300
# 	Iter:1 train-loss:1.196272 valid-loss:1.196384  train-accuracy:1.000000 valid-accuracy:1.000000
# 	Iter:2 train-loss:1.040653 valid-loss:1.040746  train-accuracy:1.000000 valid-accuracy:1.000000
# 	Iter:3 train-loss:0.910884 valid-loss:0.910962  train-accuracy:1.000000 valid-accuracy:1.000000
# 	Iter:4 train-loss:0.801193 valid-loss:0.801259  train-accuracy:1.000000 valid-accuracy:1.000000
# 	Iter:5 train-loss:0.707491 valid-loss:0.707547  train-accuracy:1.000000 valid-accuracy:1.000000
# 	Iter:6 train-loss:0.626773 valid-loss:0.626822  train-accuracy:1.000000 valid-accuracy:1.000000
# 	Iter:16 train-loss:0.206082 valid-loss:0.206097  train-accuracy:1.000000 valid-accuracy:1.000000
# 	Iter:26 train-loss:0.073115 valid-loss:0.073120  train-accuracy:1.000000 valid-accuracy:1.000000
# 	Iter:36 train-loss:0.026556 valid-loss:0.026558  train-accuracy:1.000000 valid-accuracy:1.000000
# 	Iter:46 train-loss:0.009724 valid-loss:0.009725  train-accuracy:1.000000 valid-accuracy:1.000000
# 	Iter:56 train-loss:0.003571 valid-loss:0.003571  train-accuracy:1.000000 valid-accuracy:1.000000
# 	Iter:66 train-loss:0.001313 valid-loss:0.001313  train-accuracy:1.000000 valid-accuracy:1.000000
# 	Iter:76 train-loss:0.000483 valid-loss:0.000483  train-accuracy:1.000000 valid-accuracy:1.000000
# 	Iter:86 train-loss:0.000179 valid-loss:0.000179  train-accuracy:1.000000 valid-accuracy:1.000000
# 	Iter:96 train-loss:0.000068 valid-loss:0.000068  train-accuracy:1.000000 valid-accuracy:1.000000
# 	Iter:106 train-loss:0.000028 valid-loss:0.000028  train-accuracy:1.000000 valid-accuracy:1.000000
# 	Iter:116 train-loss:0.000013 valid-loss:0.000013  train-accuracy:1.000000 valid-accuracy:1.000000
# 	Iter:126 train-loss:0.000007 valid-loss:0.000007  train-accuracy:1.000000 valid-accuracy:1.000000
# 	Iter:136 train-loss:0.000005 valid-loss:0.000005  train-accuracy:1.000000 valid-accuracy:1.000000
# 	Iter:146 train-loss:0.000004 valid-loss:0.000004  train-accuracy:1.000000 valid-accuracy:1.000000
# 	Iter:156 train-loss:0.000003 valid-loss:0.000003  train-accuracy:1.000000 valid-accuracy:1.000000
# 	Iter:166 train-loss:0.000003 valid-loss:0.000003  train-accuracy:1.000000 valid-accuracy:1.000000
# 	Iter:176 train-loss:0.000003 valid-loss:0.000003  train-accuracy:1.000000 valid-accuracy:1.000000
# 	Iter:186 train-loss:0.000002 valid-loss:0.000002  train-accuracy:1.000000 valid-accuracy:1.000000
# 	Iter:196 train-loss:0.000002 valid-loss:0.000002  train-accuracy:1.000000 valid-accuracy:1.000000
# 	Iter:206 train-loss:0.000002 valid-loss:0.000002  train-accuracy:1.000000 valid-accuracy:1.000000
# 	Iter:216 train-loss:0.000002 valid-loss:0.000002  train-accuracy:1.000000 valid-accuracy:1.000000
# 	Iter:226 train-loss:0.000002 valid-loss:0.000002  train-accuracy:1.000000 valid-accuracy:1.000000
# 	Iter:236 train-loss:0.000001 valid-loss:0.000001  train-accuracy:1.000000 valid-accuracy:1.000000
# 	Iter:246 train-loss:0.000001 valid-loss:0.000001  train-accuracy:1.000000 valid-accuracy:1.000000
# 	Iter:256 train-loss:0.000001 valid-loss:0.000001  train-accuracy:1.000000 valid-accuracy:1.000000
# 	Iter:266 train-loss:0.000001 valid-loss:0.000001  train-accuracy:1.000000 valid-accuracy:1.000000
# 	Iter:276 train-loss:0.000001 valid-loss:0.000001  train-accuracy:1.000000 valid-accuracy:1.000000
# 	Iter:286 train-loss:0.000001 valid-loss:0.000001  train-accuracy:1.000000 valid-accuracy:1.000000
# 	Iter:296 train-loss:0.000001 valid-loss:0.000001  train-accuracy:1.000000 valid-accuracy:1.000000

# %%
# Model features
model.make_inspector().features()
# Out:
# ["10Percentile" (1; #0),
#  "90Percentile" (1; #1),
#  "DependenceEntropy" (1; #2),
#  "DependenceNonUniformity" (1; #3),
#  "DependenceNonUniformityNormalized" (1; #4),
#  "DependenceVariance" (1; #5),
#  "Energy" (1; #6),
#  "Entropy" (1; #7),
#  "GrayLevelNonUniformity" (1; #8),
#  "GrayLevelVariance" (1; #9),
#  "HighGrayLevelEmphasis" (1; #10),
#  "InterquartileRange" (1; #11),
#  "Kurtosis" (1; #12),
#  "LargeDependenceEmphasis" (1; #13),
#  "LargeDependenceHighGrayLevelEmphasis" (1; #14),
#  "LargeDependenceLowGrayLevelEmphasis" (1; #15),
#  "LowGrayLevelEmphasis" (1; #16),
#  "Maximum" (1; #17),
#  "Mean" (1; #18),
#  "MeanAbsoluteDeviation" (1; #19),
#  "Median" (1; #20),
#  "Minimum" (1; #21),
#  "Range" (1; #22),
#  "RobustMeanAbsoluteDeviation" (1; #23),
#  "RootMeanSquared" (1; #24),
#  "Skewness" (1; #25),
#  "SmallDependenceEmphasis" (1; #26),
#  "SmallDependenceHighGrayLevelEmphasis" (1; #27),
#  "SmallDependenceLowGrayLevelEmphasis" (1; #28),
#  "TotalEnergy" (1; #29),
#  "Uniformity" (1; #30),
#  "Variance" (1; #31)]

# %%
# Feature importance
model.make_inspector().variable_importances()
# Out:
# {'INV_MEAN_MIN_DEPTH': [("LargeDependenceLowGrayLevelEmphasis" (1; #15),
#    0.30067971247503206),
#   ("DependenceNonUniformityNormalized" (1; #4), 0.2839246637303493),
#   ("DependenceNonUniformity" (1; #3), 0.2819720510657505),
#   ("Mean" (1; #18), 0.2803442412773191),
#   ("DependenceVariance" (1; #5), 0.24123754095228434),
#   ("LargeDependenceEmphasis" (1; #13), 0.23553791398960974),
#   ("SmallDependenceLowGrayLevelEmphasis" (1; #28), 0.23547386434381415),
#   ("SmallDependenceEmphasis" (1; #26), 0.22817942471591068),
#   ("SmallDependenceHighGrayLevelEmphasis" (1; #27), 0.22654488528560754),
#   ("Median" (1; #20), 0.22469280956250506),
#   ("LowGrayLevelEmphasis" (1; #16), 0.22073579303600696),
#   ("Energy" (1; #6), 0.21723176030184044),
#   ("TotalEnergy" (1; #29), 0.21629030344139918),
#   ("RootMeanSquared" (1; #24), 0.2157996561513241),
#   ("GrayLevelNonUniformity" (1; #8), 0.21493718975392784),
#   ("GrayLevelVariance" (1; #9), 0.21346874614714967),
#   ("LargeDependenceHighGrayLevelEmphasis" (1; #14), 0.21304441719324202),
#   ("Skewness" (1; #25), 0.21297618377496444),
#   ("DependenceEntropy" (1; #2), 0.21289295332212313),
#   ("MeanAbsoluteDeviation" (1; #19), 0.21285714883633527),
#   ("10Percentile" (1; #0), 0.21251798225394786),
#   ("InterquartileRange" (1; #11), 0.21204447462085338),
#   ("Entropy" (1; #7), 0.21193781096942246),
#   ("HighGrayLevelEmphasis" (1; #10), 0.21190846160917207),
#   ("Kurtosis" (1; #12), 0.21187604660271203),
#   ("Maximum" (1; #17), 0.21176167280349859),
#   ("Uniformity" (1; #30), 0.2116762171274453),
#   ("Minimum" (1; #21), 0.21154004286258576),
#   ("Variance" (1; #31), 0.21144381678696758),
#   ("RobustMeanAbsoluteDeviation" (1; #23), 0.2112641212998496),
#   ("Range" (1; #22), 0.21110816641651112),
#   ("90Percentile" (1; #1), 0.21110050991745688)],
#  'SUM_SCORE': [("LargeDependenceLowGrayLevelEmphasis" (1; #15),
#    1503.7358112232675),
#   ("DependenceVariance" (1; #5), 320.8473794372048),
#   ("LowGrayLevelEmphasis" (1; #16), 80.57426288724936),
#   ("LargeDependenceEmphasis" (1; #13), 8.877563542933389e-07),
#   ("DependenceNonUniformity" (1; #3), 7.496917226892441e-07),
#   ("DependenceNonUniformityNormalized" (1; #4), 6.531294250588243e-07),
#   ("SmallDependenceLowGrayLevelEmphasis" (1; #28), 6.461039410890467e-07),
#   ("SmallDependenceEmphasis" (1; #26), 6.412175219266072e-07),
#   ("Mean" (1; #18), 4.928974997465064e-07),
#   ("SmallDependenceHighGrayLevelEmphasis" (1; #27), 2.2539595935334845e-07),
#   ("Median" (1; #20), 1.730272309679041e-07),
#   ("GrayLevelNonUniformity" (1; #8), 1.5753716544914976e-07),
#   ("Energy" (1; #6), 8.416321019753625e-08),
#   ("LargeDependenceHighGrayLevelEmphasis" (1; #14), 6.209133991808348e-08),
#   ("TotalEnergy" (1; #29), 3.3934864084034644e-08),
#   ("RootMeanSquared" (1; #24), 3.337253217081637e-08),
#   ("GrayLevelVariance" (1; #9), 2.385738030340603e-08),
#   ("10Percentile" (1; #0), 2.1373202539659498e-08),
#   ("DependenceEntropy" (1; #2), 2.1178319735664422e-08),
#   ("Entropy" (1; #7), 1.8747794507082756e-08),
#   ("InterquartileRange" (1; #11), 1.4967792683075412e-08),
#   ("Kurtosis" (1; #12), 1.1990097287851602e-08),
#   ("MeanAbsoluteDeviation" (1; #19), 6.527490388065398e-09),
#   ("Uniformity" (1; #30), 3.6956488959546635e-09),
#   ("Variance" (1; #31), 1.1501291078074215e-09),
#   ("Minimum" (1; #21), 6.288400057057245e-10),
#   ("Skewness" (1; #25), 5.841923408411969e-10),
#   ("Range" (1; #22), 3.2978050573543977e-10),
#   ("RobustMeanAbsoluteDeviation" (1; #23), 7.753680918534972e-11),
#   ("HighGrayLevelEmphasis" (1; #10), 3.2594985421779264e-12),
#   ("Maximum" (1; #17), 7.196709720082168e-13),
#   ("90Percentile" (1; #1), 1.6460073389028695e-13)],
#  'NUM_AS_ROOT': [("LargeDependenceLowGrayLevelEmphasis" (1; #15), 117.0),
#   ("DependenceNonUniformityNormalized" (1; #4), 92.0),
#   ("DependenceNonUniformity" (1; #3), 90.0),
#   ("LargeDependenceHighGrayLevelEmphasis" (1; #14), 1.0)],
#  'NUM_NODES': [("DependenceVariance" (1; #5), 321.0),
#   ("SmallDependenceHighGrayLevelEmphasis" (1; #27), 298.0),
#   ("SmallDependenceLowGrayLevelEmphasis" (1; #28), 277.0),
#   ("LargeDependenceLowGrayLevelEmphasis" (1; #15), 261.0),
#   ("SmallDependenceEmphasis" (1; #26), 257.0),
#   ("Median" (1; #20), 229.0),
#   ("Mean" (1; #18), 222.0),
#   ("LargeDependenceEmphasis" (1; #13), 157.0),
#   ("DependenceNonUniformityNormalized" (1; #4), 142.0),
#   ("GrayLevelNonUniformity" (1; #8), 133.0),
#   ("DependenceNonUniformity" (1; #3), 127.0),
#   ("Skewness" (1; #25), 94.0),
#   ("GrayLevelVariance" (1; #9), 90.0),
#   ("Energy" (1; #6), 85.0),
#   ("RootMeanSquared" (1; #24), 77.0),
#   ("TotalEnergy" (1; #29), 77.0),
#   ("DependenceEntropy" (1; #2), 72.0),
#   ("LowGrayLevelEmphasis" (1; #16), 56.0),
#   ("LargeDependenceHighGrayLevelEmphasis" (1; #14), 52.0),
#   ("MeanAbsoluteDeviation" (1; #19), 48.0),
#   ("Entropy" (1; #7), 44.0),
#   ("10Percentile" (1; #0), 43.0),
#   ("Maximum" (1; #17), 42.0),
#   ("InterquartileRange" (1; #11), 40.0),
#   ("HighGrayLevelEmphasis" (1; #10), 38.0),
#   ("Kurtosis" (1; #12), 33.0),
#   ("Uniformity" (1; #30), 33.0),
#   ("Minimum" (1; #21), 22.0),
#   ("Variance" (1; #31), 22.0),
#   ("RobustMeanAbsoluteDeviation" (1; #23), 14.0),
#   ("90Percentile" (1; #1), 12.0),
#   ("Range" (1; #22), 12.0)]}

# %%
# Model self evaluation
model.make_inspector().evaluation()
# Out:
# Evaluation(num_examples=None, accuracy=1.0, loss=9.298865393247979e-07, rmse=None, ndcg=None, aucs=None, auuc=None, qini=None)

# %%
logs = model.make_inspector().training_logs()

plt.figure(figsize=(12, 4))
plt.subplot(1, 2, 1)
plt.plot([log.num_trees for log in logs], [log.evaluation.accuracy for log in logs])
plt.xlabel("Number of trees")
plt.ylabel("Accuracy (out-of-bag)")
plt.subplot(1, 2, 2)
plt.plot([log.num_trees for log in logs], [log.evaluation.loss for log in logs])
plt.xlabel("Number of trees")
plt.ylabel("Logloss (out-of-bag)")
plt.show()

# %% [markdown]
# Calculate the score of our hold-out validation dataset

# %%
predictions = model.predict(val_ds)
y_true      = validation_data["label"]

from sklearn.metrics import roc_auc_score
ROC_AUC = roc_auc_score(y_true, predictions)
print("The ROC AUC score is %.5f" % ROC_AUC )
# Out:
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 75ms/step
# The ROC AUC score is 1.00000

# %%
# Compute binary classification metrics with sklearn
import numpy as np
from sklearn.metrics import (
    accuracy_score,
    precision_score,
    recall_score,
    f1_score,
    roc_auc_score,
    average_precision_score,
    confusion_matrix,
    classification_report,
    matthews_corrcoef,
    log_loss,
    brier_score_loss,
)

# Get predictions (probabilities or class labels)
preds = model.predict(test_ds)
# If model outputs probabilities, convert to labels by threshold 0.5
if preds.ndim == 2:
    # For TFDF classification, preds may be class probabilities with shape (N, 2)
    if preds.shape[1] == 2:
        pos_probs = preds[:, 1]
    else:
        # If single-probability column (positive class)
        pos_probs = preds[:, -1]
    y_pred = (pos_probs >= 0.5).astype(int)
else:
    # Already class labels
    y_pred = preds.astype(int)
    pos_probs = None

# Ground truth labels (must be 0/1 integers)
y_true = test_data["label"].astype(int).to_numpy()

# Core metrics
metrics = {}
metrics["accuracy"] = accuracy_score(y_true, y_pred)
metrics["precision"] = precision_score(y_true, y_pred, zero_division=0)
metrics["recall"] = recall_score(y_true, y_pred, zero_division=0)
metrics["f1"] = f1_score(y_true, y_pred, zero_division=0)
metrics["mcc"] = matthews_corrcoef(y_true, y_pred)

# Probabilistic metrics (only if we have probabilities)
if pos_probs is not None:
    metrics["roc_auc"] = roc_auc_score(y_true, pos_probs)
    metrics["pr_auc"] = average_precision_score(y_true, pos_probs)
    metrics["log_loss"] = log_loss(y_true, pos_probs, labels=[0,1])
    metrics["brier_score"] = brier_score_loss(y_true, pos_probs)

# Confusion matrix and detailed report
cm = confusion_matrix(y_true, y_pred, labels=[0,1])
report = classification_report(y_true, y_pred, digits=4)

print("Sklearn binary metrics:")
for k, v in metrics.items():
    print(f"{k}: {v:.4f}")
print("\nConfusion matrix:\n", cm)
print("\nClassification report:\n", report)
# Out:
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 70ms/step
# Sklearn binary metrics:
# accuracy: 1.0000
# precision: 1.0000
# recall: 1.0000
# f1: 1.0000
# mcc: 1.0000
# roc_auc: 1.0000
# pr_auc: 1.0000
# log_loss: 0.0000
# brier_score: 0.0000
#
# Confusion matrix:
#  [[336   0]
#  [  0 106]]
#
# Classification report:
#                precision    recall  f1-score   support
#
#            0     1.0000    1.0000    1.0000       336
#            1     1.0000    1.0000    1.0000       106
#
#     accuracy                         1.0000       442
#    macro avg     1.0000    1.0000    1.0000       442
# weighted avg     1.0000    1.0000    1.0000       442
