# %%
# Import packages and modules
import numpy  as np
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow_decision_forests as tfdf

from sklearn.model_selection import train_test_split
# Out:
# 2026-08-15 05:12:40.503159: I tensorflow/core/util/port.cc:113] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2026-08-15 05:12:40.872968: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2026-08-15 05:12:45.582200: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
# Check the version of TensorFlow Decision Forests
print("Found TensorFlow Decision Forests v" + tfdf.__version__)
# Out:
# Found TensorFlow Decision Forests v1.9.1

# %%
datasetPath = 'dataset/firstorder/kernel5/dataset.csv'

# %%
# Parameters
datasetPath = "dataset/firstorder/kernel4/1.dataset.csv"

# %%
# train/validation/test = 70/10/20
dataset = pd.read_csv(datasetPath)

train_data, temp_data = train_test_split(dataset, test_size=0.3, random_state=42)
validation_data, test_data = train_test_split(temp_data, test_size=2/3, random_state=42)

# %%
from sklearn.utils.class_weight import compute_class_weight

# tinh class weight tren tap train
classes = np.array([0, 1])
weights = compute_class_weight(class_weight="balanced", classes=classes, y=train_data["label"])
class_weight = {0: weights[0], 1: weights[1]}

# gan sample_weight cho tung dong
train_data["sample_weight"] = train_data["label"].map(class_weight)
validation_data["sample_weight"] = validation_data["label"].map(class_weight)
test_data["sample_weight"] = test_data["label"].map(class_weight)

# Convert the dataset into a TensorFlow dataset.
train_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    train_data, label="label", weight="sample_weight"
)         
val_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    validation_data, label="label", weight="sample_weight"
)
test_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    test_data, label="label", weight="sample_weight"
)
# Out:
# 2026-08-15 05:12:58.640703: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:984] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2026-08-15 05:12:58.642315: W tensorflow/core/common_runtime/gpu/gpu_device.cc:2251] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...

# %%
import keras

# %%
# %%time

# Train a Random Forest model.
model = tfdf.keras.RandomForestModel()

# Add evaluation metrics
model.compile(
    metrics=["accuracy"]
)
model.fit(x=train_ds)

# # Train a Gradient Boosted Trees model.
# model = tfdf.keras.GradientBoostedTreesModel(num_trees=1500)
# model.fit(train_ds)
# Out:
# Use /tmp/tmptv9v3ukm as temporary training directory
# Reading training dataset...
# Training dataset read in 0:00:03.271206. Found 1554 examples.
# Training model...
# Model trained in 0:00:00.063173
# Compiling model...
# [INFO 26-08-15 05:13:02.1505 UTC kernel.cc:1233] Loading model from path /tmp/tmptv9v3ukm/model/ with prefix dbdc82a646144461
# [INFO 26-08-15 05:13:02.1577 UTC decision_forest.cc:734] Model loaded with 300 root(s), 5804 node(s), and 18 input feature(s).
# [INFO 26-08-15 05:13:02.1577 UTC abstract_model.cc:1362] Engine "RandomForestOptPred" built
# [INFO 26-08-15 05:13:02.1577 UTC kernel.cc:1061] Use fast generic engine
# Model compiled.
# CPU times: user 5.6 s, sys: 91.3 ms, total: 5.69 s
# Wall time: 6.5 s

# %%
# Evaluate the model
evaluate = model.evaluate(val_ds, return_dict=True)
print()

for name, value in evaluate.items():
    print(f"{name}: {value:.4f}")
# Out:
# WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 1/1 [==============================] - ETA: 0s - loss: 0.0000e+00 - accuracy: 1.0000
# 1/1 [==============================] - 3s 3s/step - loss: 0.0000e+00 - accuracy: 1.0000
# loss: 0.0000
# accuracy: 1.0000

# %%
# Model Summary
model.summary()
# Out:
# Model: "random_forest_model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
# =================================================================
# Total params: 1 (1.00 Byte)
# Trainable params: 0 (0.00 Byte)
# Non-trainable params: 1 (1.00 Byte)
# _________________________________________________________________
# Type: "RANDOM_FOREST"
# Task: CLASSIFICATION
# Label: "__LABEL"
#
# Input Features (18):
# 	10Percentile
# 	90Percentile
# 	Energy
# 	Entropy
# 	InterquartileRange
# 	Kurtosis
# 	Maximum
# 	Mean
# 	MeanAbsoluteDeviation
# 	Median
# 	Minimum
# 	Range
# 	RobustMeanAbsoluteDeviation
# 	RootMeanSquared
# 	Skewness
# 	TotalEnergy
# 	Uniformity
# 	Variance
#
# Trained with weights
#
# Variable Importance: INV_MEAN_MIN_DEPTH:
#     1.                     "Maximum"  0.333617 ################
#     2.                "90Percentile"  0.311367 #############
#     3.                 "TotalEnergy"  0.255719 ######
#     4.                      "Energy"  0.246288 #####
#     5.             "RootMeanSquared"  0.242956 ####
#     6.                     "Minimum"  0.223535 ##
#     7.                        "Mean"  0.221910 ##
#     8.                  "Uniformity"  0.217688 #
#     9.                     "Entropy"  0.216805 #
#    10.                      "Median"  0.216005 #
#    11.                    "Skewness"  0.214228 #
#    12.                    "Kurtosis"  0.211930 #
#    13.                       "Range"  0.209794
#    14.          "InterquartileRange"  0.207402
#    15.                "10Percentile"  0.207276
#    16.                    "Variance"  0.206125
#    17. "RobustMeanAbsoluteDeviation"  0.205429
#    18.       "MeanAbsoluteDeviation"  0.203764
#
# Variable Importance: NUM_AS_ROOT:
#     1.         "Maximum" 97.000000 ################
#     2.    "90Percentile" 86.000000 ##############
#     3.     "TotalEnergy" 32.000000 #####
#     4. "RootMeanSquared" 29.000000 ####
#     5.          "Energy" 25.000000 ####
#     6.            "Mean" 17.000000 ##
#     7.          "Median"  7.000000 #
#     8.         "Entropy"  4.000000
#     9.         "Minimum"  2.000000
#    10.    "10Percentile"  1.000000
#
# Variable Importance: NUM_NODES:
#     1.                     "Maximum" 347.000000 ################
#     2.                "90Percentile" 340.000000 ###############
#     3.                     "Minimum" 204.000000 ########
#     4.                  "Uniformity" 195.000000 #######
#     5.                 "TotalEnergy" 181.000000 #######
#     6.                      "Energy" 173.000000 ######
#     7.                     "Entropy" 167.000000 ######
#     8.             "RootMeanSquared" 164.000000 ######
#     9.                    "Skewness" 158.000000 #####
#    10.                      "Median" 136.000000 ####
#    11.                    "Kurtosis" 113.000000 ###
#    12.                       "Range" 109.000000 ###
#    13.                        "Mean" 103.000000 ##
#    14.                    "Variance" 89.000000 ##
#    15.          "InterquartileRange" 80.000000 #
#    16.                "10Percentile" 77.000000 #
#    17. "RobustMeanAbsoluteDeviation" 66.000000
#    18.       "MeanAbsoluteDeviation" 50.000000
#
# Variable Importance: SUM_SCORE:
#     1.                     "Maximum" 98118.630106 ################
#     2.                "90Percentile" 89588.659454 ##############
#     3.                 "TotalEnergy" 30289.772149 ####
#     4.             "RootMeanSquared" 27124.880041 ####
#     5.                      "Energy" 23486.122564 ###
#     6.                        "Mean" 14892.515560 ##
#     7.                     "Entropy" 7193.755011 #
#     8.                      "Median" 6740.825647
#     9.                  "Uniformity" 5715.984891
#    10.                     "Minimum" 4082.432531
#    11.                    "Skewness" 2414.464269
#    12.                       "Range" 1765.354150
#    13.                "10Percentile" 1463.284323
#    14.                    "Kurtosis" 1395.422578
#    15.          "InterquartileRange" 1277.541357
#    16. "RobustMeanAbsoluteDeviation" 984.866056
#    17.                    "Variance" 829.415174
#    18.       "MeanAbsoluteDeviation" 683.338339
#
#
#
# Winner takes all: true
# Out-of-bag evaluation: accuracy:0.944284 logloss:0.107038
# Number of trees: 300
# Total number of nodes: 5804
#
# Number of nodes by tree:
# Count: 300 Average: 19.3467 StdDev: 3.1091
# Min: 13 Max: 27 Ignored: 0
# ----------------------------------------------
# [ 13, 14) 13   4.33%   4.33% ##
# [ 14, 15)  0   0.00%   4.33%
# [ 15, 16) 28   9.33%  13.67% ####
# [ 16, 17)  0   0.00%  13.67%
# [ 17, 18) 62  20.67%  34.33% ########
# [ 18, 19)  0   0.00%  34.33%
# [ 19, 20) 75  25.00%  59.33% ##########
# [ 20, 21)  0   0.00%  59.33%
# [ 21, 22) 63  21.00%  80.33% ########
# [ 22, 23)  0   0.00%  80.33%
# [ 23, 24) 33  11.00%  91.33% ####
# [ 24, 25)  0   0.00%  91.33%
# [ 25, 26) 24   8.00%  99.33% ###
# [ 26, 27)  0   0.00%  99.33%
# [ 27, 27]  2   0.67% 100.00%
#
# Depth by leafs:
# Count: 3052 Average: 4.02818 StdDev: 1.51787
# Min: 1 Max: 10 Ignored: 0
# ----------------------------------------------
# [  1,  2)  58   1.90%   1.90% #
# [  2,  3) 435  14.25%  16.15% ######
# [  3,  4) 748  24.51%  40.66% ##########
# [  4,  5) 713  23.36%  64.02% ##########
# [  5,  6) 558  18.28%  82.31% #######
# [  6,  7) 344  11.27%  93.58% #####
# [  7,  8) 159   5.21%  98.79% ##
# [  8,  9)  32   1.05%  99.84%
# [  9, 10)   3   0.10%  99.93%
# [ 10, 10]   2   0.07% 100.00%
#
# Number of training obs by leaf:
# Count: 3052 Average: 152.752 StdDev: 390.223
# Min: 5 Max: 1448 Ignored: 0
# ----------------------------------------------
# [    5,   77) 2506  82.11%  82.11% ##########
# [   77,  149)  206   6.75%  88.86% #
# [  149,  221)    5   0.16%  89.02%
# [  221,  293)   19   0.62%  89.65%
# [  293,  366)   12   0.39%  90.04%
# [  366,  438)    2   0.07%  90.10%
# [  438,  510)    1   0.03%  90.14%
# [  510,  582)    1   0.03%  90.17%
# [  582,  654)    0   0.00%  90.17%
# [  654,  727)    0   0.00%  90.17%
# [  727,  799)    0   0.00%  90.17%
# [  799,  871)    0   0.00%  90.17%
# [  871,  943)    2   0.07%  90.24%
# [  943, 1015)    5   0.16%  90.40%
# [ 1015, 1088)   10   0.33%  90.73%
# [ 1088, 1160)   13   0.43%  91.15%
# [ 1160, 1232)   11   0.36%  91.51%
# [ 1232, 1304)   47   1.54%  93.05%
# [ 1304, 1376)   80   2.62%  95.67%
# [ 1376, 1448]  132   4.33% 100.00% #
#
# Attribute in nodes:
# 	347 : Maximum [NUMERICAL]
# 	340 : 90Percentile [NUMERICAL]
# 	204 : Minimum [NUMERICAL]
# 	195 : Uniformity [NUMERICAL]
# 	181 : TotalEnergy [NUMERICAL]
# 	173 : Energy [NUMERICAL]
# 	167 : Entropy [NUMERICAL]
# 	164 : RootMeanSquared [NUMERICAL]
# 	158 : Skewness [NUMERICAL]
# 	136 : Median [NUMERICAL]
# 	113 : Kurtosis [NUMERICAL]
# 	109 : Range [NUMERICAL]
# 	103 : Mean [NUMERICAL]
# 	89 : Variance [NUMERICAL]
# 	80 : InterquartileRange [NUMERICAL]
# 	77 : 10Percentile [NUMERICAL]
# 	66 : RobustMeanAbsoluteDeviation [NUMERICAL]
# 	50 : MeanAbsoluteDeviation [NUMERICAL]
#
# Attribute in nodes with depth <= 0:
# 	97 : Maximum [NUMERICAL]
# 	86 : 90Percentile [NUMERICAL]
# 	32 : TotalEnergy [NUMERICAL]
# 	29 : RootMeanSquared [NUMERICAL]
# 	25 : Energy [NUMERICAL]
# 	17 : Mean [NUMERICAL]
# 	7 : Median [NUMERICAL]
# 	4 : Entropy [NUMERICAL]
# 	2 : Minimum [NUMERICAL]
# 	1 : 10Percentile [NUMERICAL]
#
# Attribute in nodes with depth <= 1:
# 	185 : 90Percentile [NUMERICAL]
# 	184 : Maximum [NUMERICAL]
# 	96 : TotalEnergy [NUMERICAL]
# 	76 : Energy [NUMERICAL]
# 	75 : RootMeanSquared [NUMERICAL]
# 	61 : Entropy [NUMERICAL]
# 	50 : Uniformity [NUMERICAL]
# 	36 : Mean [NUMERICAL]
# 	25 : Median [NUMERICAL]
# 	12 : InterquartileRange [NUMERICAL]
# 	9 : Range [NUMERICAL]
# 	8 : Variance [NUMERICAL]
# 	7 : Minimum [NUMERICAL]
# 	6 : Skewness [NUMERICAL]
# 	5 : 10Percentile [NUMERICAL]
# 	4 : MeanAbsoluteDeviation [NUMERICAL]
# 	3 : RobustMeanAbsoluteDeviation [NUMERICAL]
#
# Attribute in nodes with depth <= 2:
# 	252 : Maximum [NUMERICAL]
# 	247 : 90Percentile [NUMERICAL]
# 	138 : TotalEnergy [NUMERICAL]
# 	121 : RootMeanSquared [NUMERICAL]
# 	113 : Energy [NUMERICAL]
# 	96 : Uniformity [NUMERICAL]
# 	95 : Entropy [NUMERICAL]
# 	76 : Median [NUMERICAL]
# 	70 : Minimum [NUMERICAL]
# 	69 : Mean [NUMERICAL]
# 	49 : Skewness [NUMERICAL]
# 	39 : Range [NUMERICAL]
# 	32 : InterquartileRange [NUMERICAL]
# 	25 : 10Percentile [NUMERICAL]
# 	19 : Variance [NUMERICAL]
# 	17 : RobustMeanAbsoluteDeviation [NUMERICAL]
# 	17 : Kurtosis [NUMERICAL]
# 	16 : MeanAbsoluteDeviation [NUMERICAL]
#
# Attribute in nodes with depth <= 3:
# 	294 : Maximum [NUMERICAL]
# 	287 : 90Percentile [NUMERICAL]
# 	162 : TotalEnergy [NUMERICAL]
# 	148 : RootMeanSquared [NUMERICAL]
# 	139 : Energy [NUMERICAL]
# 	130 : Uniformity [NUMERICAL]
# 	129 : Entropy [NUMERICAL]
# 	126 : Minimum [NUMERICAL]
# 	108 : Skewness [NUMERICAL]
# 	107 : Median [NUMERICAL]
# 	82 : Mean [NUMERICAL]
# 	70 : Range [NUMERICAL]
# 	65 : Kurtosis [NUMERICAL]
# 	43 : InterquartileRange [NUMERICAL]
# 	43 : 10Percentile [NUMERICAL]
# 	42 : Variance [NUMERICAL]
# 	41 : RobustMeanAbsoluteDeviation [NUMERICAL]
# 	25 : MeanAbsoluteDeviation [NUMERICAL]
#
# Attribute in nodes with depth <= 5:
# 	340 : Maximum [NUMERICAL]
# 	334 : 90Percentile [NUMERICAL]
# 	199 : Minimum [NUMERICAL]
# 	184 : Uniformity [NUMERICAL]
# 	177 : TotalEnergy [NUMERICAL]
# 	165 : Energy [NUMERICAL]
# 	161 : RootMeanSquared [NUMERICAL]
# 	160 : Entropy [NUMERICAL]
# 	149 : Skewness [NUMERICAL]
# 	128 : Median [NUMERICAL]
# 	106 : Range [NUMERICAL]
# 	105 : Kurtosis [NUMERICAL]
# 	99 : Mean [NUMERICAL]
# 	83 : Variance [NUMERICAL]
# 	74 : InterquartileRange [NUMERICAL]
# 	71 : 10Percentile [NUMERICAL]
# 	62 : RobustMeanAbsoluteDeviation [NUMERICAL]
# 	47 : MeanAbsoluteDeviation [NUMERICAL]
#
# Condition type in nodes:
# 	2752 : HigherCondition
# Condition type in nodes with depth <= 0:
# 	300 : HigherCondition
# Condition type in nodes with depth <= 1:
# 	842 : HigherCondition
# Condition type in nodes with depth <= 2:
# 	1491 : HigherCondition
# Condition type in nodes with depth <= 3:
# 	2041 : HigherCondition
# Condition type in nodes with depth <= 5:
# 	2644 : HigherCondition
# Node format: NOT_SET
#
# Training OOB:
# 	trees: 1, Out-of-bag evaluation: accuracy:0.927279 logloss:2.62111
# 	trees: 12, Out-of-bag evaluation: accuracy:0.938483 logloss:1.59428
# 	trees: 22, Out-of-bag evaluation: accuracy:0.944951 logloss:1.00604
# 	trees: 32, Out-of-bag evaluation: accuracy:0.954125 logloss:0.438979
# 	trees: 42, Out-of-bag evaluation: accuracy:0.948519 logloss:0.268271
# 	trees: 52, Out-of-bag evaluation: accuracy:0.960074 logloss:0.2741
# 	trees: 62, Out-of-bag evaluation: accuracy:0.954468 logloss:0.107992
# 	trees: 74, Out-of-bag evaluation: accuracy:0.949547 logloss:0.111054
# 	trees: 84, Out-of-bag evaluation: accuracy:0.949547 logloss:0.109754
# 	trees: 94, Out-of-bag evaluation: accuracy:0.949205 logloss:0.1109
# 	trees: 106, Out-of-bag evaluation: accuracy:0.949547 logloss:0.111563
# 	trees: 116, Out-of-bag evaluation: accuracy:0.949547 logloss:0.111984
# 	trees: 126, Out-of-bag evaluation: accuracy:0.95481 logloss:0.113047
# 	trees: 136, Out-of-bag evaluation: accuracy:0.94989 logloss:0.114272
# 	trees: 146, Out-of-bag evaluation: accuracy:0.94989 logloss:0.109326
# 	trees: 156, Out-of-bag evaluation: accuracy:0.944627 logloss:0.109379
# 	trees: 166, Out-of-bag evaluation: accuracy:0.944284 logloss:0.106322
# 	trees: 176, Out-of-bag evaluation: accuracy:0.944627 logloss:0.102368
# 	trees: 187, Out-of-bag evaluation: accuracy:0.944284 logloss:0.102081
# 	trees: 197, Out-of-bag evaluation: accuracy:0.944284 logloss:0.101716
# 	trees: 207, Out-of-bag evaluation: accuracy:0.949547 logloss:0.102837
# 	trees: 217, Out-of-bag evaluation: accuracy:0.944284 logloss:0.102995
# 	trees: 227, Out-of-bag evaluation: accuracy:0.944284 logloss:0.103481
# 	trees: 237, Out-of-bag evaluation: accuracy:0.944284 logloss:0.104104
# 	trees: 247, Out-of-bag evaluation: accuracy:0.944284 logloss:0.105532
# 	trees: 257, Out-of-bag evaluation: accuracy:0.944284 logloss:0.10618
# 	trees: 269, Out-of-bag evaluation: accuracy:0.944284 logloss:0.1064
# 	trees: 279, Out-of-bag evaluation: accuracy:0.944284 logloss:0.106545
# 	trees: 289, Out-of-bag evaluation: accuracy:0.944284 logloss:0.106818
# 	trees: 299, Out-of-bag evaluation: accuracy:0.944284 logloss:0.10699
# 	trees: 300, Out-of-bag evaluation: accuracy:0.944284 logloss:0.107038

# %%
# Model features
model.make_inspector().features()
# Out:
# ["10Percentile" (1; #0),
#  "90Percentile" (1; #1),
#  "Energy" (1; #2),
#  "Entropy" (1; #3),
#  "InterquartileRange" (1; #4),
#  "Kurtosis" (1; #5),
#  "Maximum" (1; #6),
#  "Mean" (1; #7),
#  "MeanAbsoluteDeviation" (1; #8),
#  "Median" (1; #9),
#  "Minimum" (1; #10),
#  "Range" (1; #11),
#  "RobustMeanAbsoluteDeviation" (1; #12),
#  "RootMeanSquared" (1; #13),
#  "Skewness" (1; #14),
#  "TotalEnergy" (1; #15),
#  "Uniformity" (1; #16),
#  "Variance" (1; #17)]

# %%
# Feature importance
model.make_inspector().variable_importances()
# Out:
# {'INV_MEAN_MIN_DEPTH': [("Maximum" (1; #6), 0.333616978330536),
#   ("90Percentile" (1; #1), 0.3113667007984954),
#   ("TotalEnergy" (1; #15), 0.2557193654483896),
#   ("Energy" (1; #2), 0.24628829710061537),
#   ("RootMeanSquared" (1; #13), 0.24295600681994683),
#   ("Minimum" (1; #10), 0.2235351058019128),
#   ("Mean" (1; #7), 0.22190953744029657),
#   ("Uniformity" (1; #16), 0.21768841351727627),
#   ("Entropy" (1; #3), 0.21680467412170623),
#   ("Median" (1; #9), 0.21600485482240153),
#   ("Skewness" (1; #14), 0.21422796915921793),
#   ("Kurtosis" (1; #5), 0.21192964037093825),
#   ("Range" (1; #11), 0.2097939108995978),
#   ("InterquartileRange" (1; #4), 0.20740191234201577),
#   ("10Percentile" (1; #0), 0.20727617604007761),
#   ("Variance" (1; #17), 0.20612458119885876),
#   ("RobustMeanAbsoluteDeviation" (1; #12), 0.20542949267434035),
#   ("MeanAbsoluteDeviation" (1; #8), 0.2037641312454972)],
#  'NUM_AS_ROOT': [("Maximum" (1; #6), 97.0),
#   ("90Percentile" (1; #1), 86.0),
#   ("TotalEnergy" (1; #15), 32.0),
#   ("RootMeanSquared" (1; #13), 29.0),
#   ("Energy" (1; #2), 25.0),
#   ("Mean" (1; #7), 17.0),
#   ("Median" (1; #9), 7.0),
#   ("Entropy" (1; #3), 4.0),
#   ("Minimum" (1; #10), 2.0),
#   ("10Percentile" (1; #0), 1.0)],
#  'SUM_SCORE': [("Maximum" (1; #6), 98118.6301062275),
#   ("90Percentile" (1; #1), 89588.65945390734),
#   ("TotalEnergy" (1; #15), 30289.772148776698),
#   ("RootMeanSquared" (1; #13), 27124.88004109458),
#   ("Energy" (1; #2), 23486.122564215664),
#   ("Mean" (1; #7), 14892.515560341451),
#   ("Entropy" (1; #3), 7193.755011058982),
#   ("Median" (1; #9), 6740.825646741817),
#   ("Uniformity" (1; #16), 5715.984890543872),
#   ("Minimum" (1; #10), 4082.432531090872),
#   ("Skewness" (1; #14), 2414.464268965611),
#   ("Range" (1; #11), 1765.3541504462776),
#   ("10Percentile" (1; #0), 1463.2843229435673),
#   ("Kurtosis" (1; #5), 1395.4225778821192),
#   ("InterquartileRange" (1; #4), 1277.5413573738902),
#   ("RobustMeanAbsoluteDeviation" (1; #12), 984.866055522249),
#   ("Variance" (1; #17), 829.4151736020759),
#   ("MeanAbsoluteDeviation" (1; #8), 683.3383392908738)],
#  'NUM_NODES': [("Maximum" (1; #6), 347.0),
#   ("90Percentile" (1; #1), 340.0),
#   ("Minimum" (1; #10), 204.0),
#   ("Uniformity" (1; #16), 195.0),
#   ("TotalEnergy" (1; #15), 181.0),
#   ("Energy" (1; #2), 173.0),
#   ("Entropy" (1; #3), 167.0),
#   ("RootMeanSquared" (1; #13), 164.0),
#   ("Skewness" (1; #14), 158.0),
#   ("Median" (1; #9), 136.0),
#   ("Kurtosis" (1; #5), 113.0),
#   ("Range" (1; #11), 109.0),
#   ("Mean" (1; #7), 103.0),
#   ("Variance" (1; #17), 89.0),
#   ("InterquartileRange" (1; #4), 80.0),
#   ("10Percentile" (1; #0), 77.0),
#   ("RobustMeanAbsoluteDeviation" (1; #12), 66.0),
#   ("MeanAbsoluteDeviation" (1; #8), 50.0)]}

# %%
# Model self evaluation
model.make_inspector().evaluation()
# Out:
# Evaluation(num_examples=1554, accuracy=0.9442841159440322, loss=0.10703833100579037, rmse=None, ndcg=None, aucs=None, auuc=None, qini=None)

# %%
logs = model.make_inspector().training_logs()

plt.figure(figsize=(12, 4))
plt.subplot(1, 2, 1)
plt.plot([log.num_trees for log in logs], [log.evaluation.accuracy for log in logs])
plt.xlabel("Number of trees")
plt.ylabel("Accuracy (out-of-bag)")
plt.subplot(1, 2, 2)
plt.plot([log.num_trees for log in logs], [log.evaluation.loss for log in logs])
plt.xlabel("Number of trees")
plt.ylabel("Logloss (out-of-bag)")
plt.show()

# %% [markdown]
# Calculate the score of our hold-out validation dataset

# %%
predictions = model.predict(val_ds)
y_true      = validation_data["label"]

from sklearn.metrics import roc_auc_score
ROC_AUC = roc_auc_score(y_true, predictions)
print("The ROC AUC score is %.5f" % ROC_AUC )
# Out:
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 64ms/step
# The ROC AUC score is 1.00000

# %%
# Compute binary classification metrics with sklearn
import numpy as np
from sklearn.metrics import (
    accuracy_score,
    precision_score,
    recall_score,
    f1_score,
    roc_auc_score,
    average_precision_score,
    confusion_matrix,
    classification_report,
    matthews_corrcoef,
    log_loss,
    brier_score_loss,
)

# Get predictions (probabilities or class labels)
preds = model.predict(test_ds)
# If model outputs probabilities, convert to labels by threshold 0.5
if preds.ndim == 2:
    # For TFDF classification, preds may be class probabilities with shape (N, 2)
    if preds.shape[1] == 2:
        pos_probs = preds[:, 1]
    else:
        # If single-probability column (positive class)
        pos_probs = preds[:, -1]
    y_pred = (pos_probs >= 0.5).astype(int)
else:
    # Already class labels
    y_pred = preds.astype(int)
    pos_probs = None

# Ground truth labels (must be 0/1 integers)
y_true = test_data["label"].astype(int).to_numpy()

# Core metrics
metrics = {}
metrics["accuracy"] = accuracy_score(y_true, y_pred)
metrics["precision"] = precision_score(y_true, y_pred, zero_division=0)
metrics["recall"] = recall_score(y_true, y_pred, zero_division=0)
metrics["f1"] = f1_score(y_true, y_pred, zero_division=0)
metrics["mcc"] = matthews_corrcoef(y_true, y_pred)

# Probabilistic metrics (only if we have probabilities)
if pos_probs is not None:
    metrics["roc_auc"] = roc_auc_score(y_true, pos_probs)
    metrics["pr_auc"] = average_precision_score(y_true, pos_probs)
    metrics["log_loss"] = log_loss(y_true, pos_probs, labels=[0,1])
    metrics["brier_score"] = brier_score_loss(y_true, pos_probs)

# Confusion matrix and detailed report
cm = confusion_matrix(y_true, y_pred, labels=[0,1])
report = classification_report(y_true, y_pred, digits=4)

print("Sklearn binary metrics:")
for k, v in metrics.items():
    print(f"{k}: {v:.4f}")
print("\nConfusion matrix:\n", cm)
print("\nClassification report:\n", report)
# Out:
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 67ms/step
# Sklearn binary metrics:
# accuracy: 0.9865
# precision: 0.8649
# recall: 0.9697
# f1: 0.9143
# mcc: 0.9087
# roc_auc: 0.9991
# pr_auc: 0.9909
# log_loss: 0.0311
# brier_score: 0.0104
#
# Confusion matrix:
#  [[406   5]
#  [  1  32]]
#
# Classification report:
#                precision    recall  f1-score   support
#
#            0     0.9975    0.9878    0.9927       411
#            1     0.8649    0.9697    0.9143        33
#
#     accuracy                         0.9865       444
#    macro avg     0.9312    0.9788    0.9535       444
# weighted avg     0.9877    0.9865    0.9868       444
