# %%
# Import packages and modules
import numpy  as np
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow_decision_forests as tfdf

from sklearn.model_selection import train_test_split
# Out:
# 2026-08-12 05:52:46.688459: I tensorflow/core/util/port.cc:113] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2026-08-12 05:52:47.167684: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2026-08-12 05:52:55.420315: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
# Check the version of TensorFlow Decision Forests
print("Found TensorFlow Decision Forests v" + tfdf.__version__)
# Out:
# Found TensorFlow Decision Forests v1.9.1

# %%
datasetPath = 'dataset/firstorder/kernel5-radius5/dataset.csv'

# %%
# Parameters
datasetPath = "dataset/firstorder/kernel4-radius4/1.dataset.csv"

# %%
# train/validation/test = 70/10/20
dataset = pd.read_csv(datasetPath)

train_data, temp_data = train_test_split(dataset, test_size=0.3, random_state=42)
validation_data, test_data = train_test_split(temp_data, test_size=2/3, random_state=42)

# %%
from sklearn.utils.class_weight import compute_class_weight

# tinh class weight tren tap train
classes = np.array([0, 1])
weights = compute_class_weight(class_weight="balanced", classes=classes, y=train_data["label"])
class_weight = {0: weights[0], 1: weights[1]}

# gan sample_weight cho tung dong
train_data["sample_weight"] = train_data["label"].map(class_weight)
validation_data["sample_weight"] = validation_data["label"].map(class_weight)
test_data["sample_weight"] = test_data["label"].map(class_weight)

# Convert the dataset into a TensorFlow dataset.
train_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    train_data, label="label", weight="sample_weight"
)         
val_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    validation_data, label="label", weight="sample_weight"
)
test_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    test_data, label="label", weight="sample_weight"
)
# Out:
# 2026-08-12 05:53:10.776634: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:984] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2026-08-12 05:53:10.778381: W tensorflow/core/common_runtime/gpu/gpu_device.cc:2251] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...

# %%
import keras

# %%
# %%time

# Train a Random Forest model.
model = tfdf.keras.RandomForestModel()

# Add evaluation metrics
model.compile(
    metrics=["accuracy"]
)
model.fit(x=train_ds)

# # Train a Gradient Boosted Trees model.
# model = tfdf.keras.GradientBoostedTreesModel(num_trees=1500)
# model.fit(train_ds)
# Out:
# Use /tmp/tmp67lm1ezd as temporary training directory
# Reading training dataset...
# Training dataset read in 0:00:02.825466. Found 1336 examples.
# Training model...
# Model trained in 0:00:00.123475
# Compiling model...
# [INFO 26-08-12 05:53:13.8774 UTC kernel.cc:1233] Loading model from path /tmp/tmp67lm1ezd/model/ with prefix b5027b395ce24092
# [INFO 26-08-12 05:53:13.8994 UTC decision_forest.cc:734] Model loaded with 300 root(s), 18138 node(s), and 18 input feature(s).
# [INFO 26-08-12 05:53:13.8994 UTC abstract_model.cc:1362] Engine "RandomForestOptPred" built
# [INFO 26-08-12 05:53:13.8994 UTC kernel.cc:1061] Use fast generic engine
# Model compiled.
# CPU times: user 6.83 s, sys: 56.6 ms, total: 6.88 s
# Wall time: 6.5 s

# %%
# Evaluate the model
evaluate = model.evaluate(val_ds, return_dict=True)
print()

for name, value in evaluate.items():
    print(f"{name}: {value:.4f}")
# Out:
# WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 1/1 [==============================] - ETA: 0s - loss: 0.0000e+00 - accuracy: 0.9686
# 1/1 [==============================] - 3s 3s/step - loss: 0.0000e+00 - accuracy: 0.9686
# loss: 0.0000
# accuracy: 0.9686

# %%
# Model Summary
model.summary()
# Out:
# Model: "random_forest_model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
# =================================================================
# Total params: 1 (1.00 Byte)
# Trainable params: 0 (0.00 Byte)
# Non-trainable params: 1 (1.00 Byte)
# _________________________________________________________________
# Type: "RANDOM_FOREST"
# Task: CLASSIFICATION
# Label: "__LABEL"
#
# Input Features (18):
# 	10Percentile
# 	90Percentile
# 	Energy
# 	Entropy
# 	InterquartileRange
# 	Kurtosis
# 	Maximum
# 	Mean
# 	MeanAbsoluteDeviation
# 	Median
# 	Minimum
# 	Range
# 	RobustMeanAbsoluteDeviation
# 	RootMeanSquared
# 	Skewness
# 	TotalEnergy
# 	Uniformity
# 	Variance
#
# Trained with weights
#
# Variable Importance: INV_MEAN_MIN_DEPTH:
#     1.                      "Median"  0.214179 ################
#     2.                 "TotalEnergy"  0.199408 ############
#     3.             "RootMeanSquared"  0.196238 ###########
#     4.                      "Energy"  0.196141 ###########
#     5.                        "Mean"  0.192530 ##########
#     6.                "10Percentile"  0.181148 ########
#     7.                  "Uniformity"  0.163587 ####
#     8.          "InterquartileRange"  0.161975 ###
#     9.                     "Maximum"  0.156895 ##
#    10.                     "Entropy"  0.156335 ##
#    11. "RobustMeanAbsoluteDeviation"  0.155808 ##
#    12.                "90Percentile"  0.152763 #
#    13.                    "Skewness"  0.150493
#    14.                     "Minimum"  0.147699
#    15.       "MeanAbsoluteDeviation"  0.147190
#    16.                    "Kurtosis"  0.146972
#    17.                       "Range"  0.146957
#    18.                    "Variance"  0.146550
#
# Variable Importance: NUM_AS_ROOT:
#     1.          "Energy" 58.000000 ################
#     2. "RootMeanSquared" 56.000000 ###############
#     3.     "TotalEnergy" 56.000000 ###############
#     4.            "Mean" 51.000000 ##############
#     5.          "Median" 51.000000 ##############
#     6.    "10Percentile" 16.000000 ####
#     7.         "Maximum"  7.000000 #
#     8.    "90Percentile"  4.000000
#     9.      "Uniformity"  1.000000
#
# Variable Importance: NUM_NODES:
#     1.                      "Median" 778.000000 ################
#     2.                     "Maximum" 620.000000 ##########
#     3.                        "Mean" 605.000000 ##########
#     4.                  "Uniformity" 592.000000 #########
#     5.                     "Entropy" 547.000000 ########
#     6.             "RootMeanSquared" 537.000000 #######
#     7.          "InterquartileRange" 518.000000 #######
#     8.                 "TotalEnergy" 513.000000 #######
#     9.                "10Percentile" 508.000000 ######
#    10.                      "Energy" 495.000000 ######
#    11.                    "Skewness" 476.000000 #####
#    12. "RobustMeanAbsoluteDeviation" 470.000000 #####
#    13.                "90Percentile" 430.000000 ####
#    14.                       "Range" 424.000000 ####
#    15.                    "Kurtosis" 399.000000 ###
#    16.                     "Minimum" 360.000000 #
#    17.       "MeanAbsoluteDeviation" 346.000000 #
#    18.                    "Variance" 301.000000
#
# Variable Importance: SUM_SCORE:
#     1.                      "Median" 39931.933924 ################
#     2.                      "Energy" 39663.238697 ###############
#     3.                 "TotalEnergy" 38757.307202 ###############
#     4.             "RootMeanSquared" 38652.419740 ###############
#     5.                        "Mean" 35416.280315 ##############
#     6.                "10Percentile" 16252.705336 #####
#     7.                     "Maximum" 7997.221783 ##
#     8.                  "Uniformity" 6417.813795 #
#     9.                "90Percentile" 5984.016186 #
#    10.          "InterquartileRange" 5434.737925 #
#    11.                     "Entropy" 4707.340474
#    12. "RobustMeanAbsoluteDeviation" 4681.617826
#    13.                    "Skewness" 3515.957691
#    14.                       "Range" 3170.635101
#    15.                    "Kurtosis" 3055.080141
#    16.                     "Minimum" 2859.881716
#    17.       "MeanAbsoluteDeviation" 2591.849180
#    18.                    "Variance" 2368.056150
#
#
#
# Winner takes all: true
# Out-of-bag evaluation: accuracy:0.890495 logloss:0.501785
# Number of trees: 300
# Total number of nodes: 18138
#
# Number of nodes by tree:
# Count: 300 Average: 60.46 StdDev: 6.21088
# Min: 45 Max: 77 Ignored: 0
# ----------------------------------------------
# [ 45, 46)  2   0.67%   0.67% #
# [ 46, 48)  5   1.67%   2.33% #
# [ 48, 49)  0   0.00%   2.33%
# [ 49, 51)  7   2.33%   4.67% ##
# [ 51, 53) 12   4.00%   8.67% ###
# [ 53, 54) 17   5.67%  14.33% ####
# [ 54, 56) 27   9.00%  23.33% #######
# [ 56, 58) 40  13.33%  36.67% ##########
# [ 58, 59)  0   0.00%  36.67%
# [ 59, 61) 34  11.33%  48.00% #########
# [ 61, 63) 38  12.67%  60.67% ##########
# [ 63, 64) 29   9.67%  70.33% #######
# [ 64, 66) 30  10.00%  80.33% ########
# [ 66, 68) 24   8.00%  88.33% ######
# [ 68, 69)  0   0.00%  88.33%
# [ 69, 71) 17   5.67%  94.00% ####
# [ 71, 73)  9   3.00%  97.00% ##
# [ 73, 74)  4   1.33%  98.33% #
# [ 74, 76)  3   1.00%  99.33% #
# [ 76, 77]  2   0.67% 100.00% #
#
# Depth by leafs:
# Count: 9219 Average: 6.31131 StdDev: 2.21147
# Min: 1 Max: 15 Ignored: 0
# ----------------------------------------------
# [  1,  2)    9   0.10%   0.10%
# [  2,  3)  208   2.26%   2.35% #
# [  3,  4)  627   6.80%   9.16% ####
# [  4,  5) 1222  13.26%  22.41% ########
# [  5,  6) 1495  16.22%  38.63% ##########
# [  6,  7) 1548  16.79%  55.42% ##########
# [  7,  8) 1442  15.64%  71.06% #########
# [  8,  9) 1183  12.83%  83.89% ########
# [  9, 10)  726   7.88%  91.77% #####
# [ 10, 11)  431   4.68%  96.44% ###
# [ 11, 12)  188   2.04%  98.48% #
# [ 12, 13)   87   0.94%  99.43% #
# [ 13, 14)   33   0.36%  99.78%
# [ 14, 15)   16   0.17%  99.96%
# [ 15, 15]    4   0.04% 100.00%
#
# Number of training obs by leaf:
# Count: 9219 Average: 43.4754 StdDev: 138.744
# Min: 5 Max: 907 Ignored: 0
# ----------------------------------------------
# [   5,  50) 8031  87.11%  87.11% ##########
# [  50,  95)  569   6.17%  93.29% #
# [  95, 140)  275   2.98%  96.27%
# [ 140, 185)   22   0.24%  96.51%
# [ 185, 230)   11   0.12%  96.63%
# [ 230, 275)    7   0.08%  96.70%
# [ 275, 321)    1   0.01%  96.71%
# [ 321, 366)    2   0.02%  96.74%
# [ 366, 411)    1   0.01%  96.75%
# [ 411, 456)    1   0.01%  96.76%
# [ 456, 501)    3   0.03%  96.79%
# [ 501, 546)    0   0.00%  96.79%
# [ 546, 591)    5   0.05%  96.84%
# [ 591, 637)   12   0.13%  96.97%
# [ 637, 682)   17   0.18%  97.16%
# [ 682, 727)   15   0.16%  97.32%
# [ 727, 772)   62   0.67%  97.99%
# [ 772, 817)   74   0.80%  98.80%
# [ 817, 862)   67   0.73%  99.52%
# [ 862, 907]   44   0.48% 100.00%
#
# Attribute in nodes:
# 	778 : Median [NUMERICAL]
# 	620 : Maximum [NUMERICAL]
# 	605 : Mean [NUMERICAL]
# 	592 : Uniformity [NUMERICAL]
# 	547 : Entropy [NUMERICAL]
# 	537 : RootMeanSquared [NUMERICAL]
# 	518 : InterquartileRange [NUMERICAL]
# 	513 : TotalEnergy [NUMERICAL]
# 	508 : 10Percentile [NUMERICAL]
# 	495 : Energy [NUMERICAL]
# 	476 : Skewness [NUMERICAL]
# 	470 : RobustMeanAbsoluteDeviation [NUMERICAL]
# 	430 : 90Percentile [NUMERICAL]
# 	424 : Range [NUMERICAL]
# 	399 : Kurtosis [NUMERICAL]
# 	360 : Minimum [NUMERICAL]
# 	346 : MeanAbsoluteDeviation [NUMERICAL]
# 	301 : Variance [NUMERICAL]
#
# Attribute in nodes with depth <= 0:
# 	58 : Energy [NUMERICAL]
# 	56 : TotalEnergy [NUMERICAL]
# 	56 : RootMeanSquared [NUMERICAL]
# 	51 : Median [NUMERICAL]
# 	51 : Mean [NUMERICAL]
# 	16 : 10Percentile [NUMERICAL]
# 	7 : Maximum [NUMERICAL]
# 	4 : 90Percentile [NUMERICAL]
# 	1 : Uniformity [NUMERICAL]
#
# Attribute in nodes with depth <= 1:
# 	151 : Median [NUMERICAL]
# 	150 : TotalEnergy [NUMERICAL]
# 	145 : RootMeanSquared [NUMERICAL]
# 	140 : Energy [NUMERICAL]
# 	131 : Mean [NUMERICAL]
# 	107 : 10Percentile [NUMERICAL]
# 	28 : 90Percentile [NUMERICAL]
# 	12 : Minimum [NUMERICAL]
# 	10 : Maximum [NUMERICAL]
# 	3 : RobustMeanAbsoluteDeviation [NUMERICAL]
# 	3 : MeanAbsoluteDeviation [NUMERICAL]
# 	2 : Uniformity [NUMERICAL]
# 	2 : Skewness [NUMERICAL]
# 	2 : Kurtosis [NUMERICAL]
# 	2 : InterquartileRange [NUMERICAL]
# 	2 : Entropy [NUMERICAL]
# 	1 : Range [NUMERICAL]
#
# Attribute in nodes with depth <= 2:
# 	284 : Median [NUMERICAL]
# 	218 : Mean [NUMERICAL]
# 	203 : TotalEnergy [NUMERICAL]
# 	201 : Energy [NUMERICAL]
# 	189 : RootMeanSquared [NUMERICAL]
# 	178 : 10Percentile [NUMERICAL]
# 	81 : Uniformity [NUMERICAL]
# 	76 : 90Percentile [NUMERICAL]
# 	73 : InterquartileRange [NUMERICAL]
# 	67 : RobustMeanAbsoluteDeviation [NUMERICAL]
# 	63 : Entropy [NUMERICAL]
# 	45 : Skewness [NUMERICAL]
# 	44 : Maximum [NUMERICAL]
# 	41 : Minimum [NUMERICAL]
# 	36 : MeanAbsoluteDeviation [NUMERICAL]
# 	29 : Range [NUMERICAL]
# 	24 : Kurtosis [NUMERICAL]
# 	13 : Variance [NUMERICAL]
#
# Attribute in nodes with depth <= 3:
# 	418 : Median [NUMERICAL]
# 	292 : Mean [NUMERICAL]
# 	272 : Energy [NUMERICAL]
# 	266 : TotalEnergy [NUMERICAL]
# 	261 : RootMeanSquared [NUMERICAL]
# 	243 : 10Percentile [NUMERICAL]
# 	187 : InterquartileRange [NUMERICAL]
# 	175 : Uniformity [NUMERICAL]
# 	148 : RobustMeanAbsoluteDeviation [NUMERICAL]
# 	147 : 90Percentile [NUMERICAL]
# 	138 : Entropy [NUMERICAL]
# 	130 : Maximum [NUMERICAL]
# 	114 : Skewness [NUMERICAL]
# 	89 : MeanAbsoluteDeviation [NUMERICAL]
# 	84 : Minimum [NUMERICAL]
# 	81 : Range [NUMERICAL]
# 	78 : Kurtosis [NUMERICAL]
# 	63 : Variance [NUMERICAL]
#
# Attribute in nodes with depth <= 5:
# 	600 : Median [NUMERICAL]
# 	440 : Mean [NUMERICAL]
# 	396 : RootMeanSquared [NUMERICAL]
# 	386 : Maximum [NUMERICAL]
# 	385 : Uniformity [NUMERICAL]
# 	385 : 10Percentile [NUMERICAL]
# 	383 : TotalEnergy [NUMERICAL]
# 	368 : Energy [NUMERICAL]
# 	360 : InterquartileRange [NUMERICAL]
# 	326 : Entropy [NUMERICAL]
# 	300 : RobustMeanAbsoluteDeviation [NUMERICAL]
# 	274 : Skewness [NUMERICAL]
# 	264 : 90Percentile [NUMERICAL]
# 	245 : Range [NUMERICAL]
# 	238 : Kurtosis [NUMERICAL]
# 	219 : Minimum [NUMERICAL]
# 	209 : MeanAbsoluteDeviation [NUMERICAL]
# 	173 : Variance [NUMERICAL]
#
# Condition type in nodes:
# 	8919 : HigherCondition
# Condition type in nodes with depth <= 0:
# 	300 : HigherCondition
# Condition type in nodes with depth <= 1:
# 	891 : HigherCondition
# Condition type in nodes with depth <= 2:
# 	1865 : HigherCondition
# Condition type in nodes with depth <= 3:
# 	3186 : HigherCondition
# Condition type in nodes with depth <= 5:
# 	5951 : HigherCondition
# Node format: NOT_SET
#
# Training OOB:
# 	trees: 1, Out-of-bag evaluation: accuracy:0.879807 logloss:4.33221
# 	trees: 11, Out-of-bag evaluation: accuracy:0.881859 logloss:2.98233
# 	trees: 21, Out-of-bag evaluation: accuracy:0.884163 logloss:1.22095
# 	trees: 31, Out-of-bag evaluation: accuracy:0.882862 logloss:0.848469
# 	trees: 41, Out-of-bag evaluation: accuracy:0.885898 logloss:0.636851
# 	trees: 53, Out-of-bag evaluation: accuracy:0.887329 logloss:0.545877
# 	trees: 63, Out-of-bag evaluation: accuracy:0.891492 logloss:0.533757
# 	trees: 73, Out-of-bag evaluation: accuracy:0.885594 logloss:0.535059
# 	trees: 83, Out-of-bag evaluation: accuracy:0.882428 logloss:0.535977
# 	trees: 93, Out-of-bag evaluation: accuracy:0.885594 logloss:0.52913
# 	trees: 103, Out-of-bag evaluation: accuracy:0.886028 logloss:0.529478
# 	trees: 113, Out-of-bag evaluation: accuracy:0.886028 logloss:0.51174
# 	trees: 124, Out-of-bag evaluation: accuracy:0.89236 logloss:0.510239
# 	trees: 134, Out-of-bag evaluation: accuracy:0.891926 logloss:0.512185
# 	trees: 144, Out-of-bag evaluation: accuracy:0.889194 logloss:0.51326
# 	trees: 154, Out-of-bag evaluation: accuracy:0.888326 logloss:0.515724
# 	trees: 164, Out-of-bag evaluation: accuracy:0.88876 logloss:0.515599
# 	trees: 174, Out-of-bag evaluation: accuracy:0.889627 logloss:0.51312
# 	trees: 184, Out-of-bag evaluation: accuracy:0.889627 logloss:0.51439
# 	trees: 194, Out-of-bag evaluation: accuracy:0.889627 logloss:0.51484
# 	trees: 204, Out-of-bag evaluation: accuracy:0.893227 logloss:0.513559
# 	trees: 214, Out-of-bag evaluation: accuracy:0.893227 logloss:0.514006
# 	trees: 224, Out-of-bag evaluation: accuracy:0.893227 logloss:0.515341
# 	trees: 234, Out-of-bag evaluation: accuracy:0.893227 logloss:0.515334
# 	trees: 246, Out-of-bag evaluation: accuracy:0.895526 logloss:0.515225
# 	trees: 257, Out-of-bag evaluation: accuracy:0.895526 logloss:0.50023
# 	trees: 267, Out-of-bag evaluation: accuracy:0.89236 logloss:0.500008
# 	trees: 277, Out-of-bag evaluation: accuracy:0.893227 logloss:0.500424
# 	trees: 287, Out-of-bag evaluation: accuracy:0.892793 logloss:0.501468
# 	trees: 297, Out-of-bag evaluation: accuracy:0.893227 logloss:0.501859
# 	trees: 300, Out-of-bag evaluation: accuracy:0.890495 logloss:0.501785

# %%
# Model features
model.make_inspector().features()
# Out:
# ["10Percentile" (1; #0),
#  "90Percentile" (1; #1),
#  "Energy" (1; #2),
#  "Entropy" (1; #3),
#  "InterquartileRange" (1; #4),
#  "Kurtosis" (1; #5),
#  "Maximum" (1; #6),
#  "Mean" (1; #7),
#  "MeanAbsoluteDeviation" (1; #8),
#  "Median" (1; #9),
#  "Minimum" (1; #10),
#  "Range" (1; #11),
#  "RobustMeanAbsoluteDeviation" (1; #12),
#  "RootMeanSquared" (1; #13),
#  "Skewness" (1; #14),
#  "TotalEnergy" (1; #15),
#  "Uniformity" (1; #16),
#  "Variance" (1; #17)]

# %%
# Feature importance
model.make_inspector().variable_importances()
# Out:
# {'INV_MEAN_MIN_DEPTH': [("Median" (1; #9), 0.21417856335208726),
#   ("TotalEnergy" (1; #15), 0.19940824587201003),
#   ("RootMeanSquared" (1; #13), 0.19623802396661902),
#   ("Energy" (1; #2), 0.19614140763332752),
#   ("Mean" (1; #7), 0.19252979390096958),
#   ("10Percentile" (1; #0), 0.1811484505463035),
#   ("Uniformity" (1; #16), 0.1635871758624247),
#   ("InterquartileRange" (1; #4), 0.16197515101028412),
#   ("Maximum" (1; #6), 0.1568949814082665),
#   ("Entropy" (1; #3), 0.15633473817016777),
#   ("RobustMeanAbsoluteDeviation" (1; #12), 0.1558079456501652),
#   ("90Percentile" (1; #1), 0.15276325360022144),
#   ("Skewness" (1; #14), 0.15049266867624844),
#   ("Minimum" (1; #10), 0.14769915811048182),
#   ("MeanAbsoluteDeviation" (1; #8), 0.14719047590986387),
#   ("Kurtosis" (1; #5), 0.14697150543680304),
#   ("Range" (1; #11), 0.1469570955391449),
#   ("Variance" (1; #17), 0.14655040828170493)],
#  'NUM_AS_ROOT': [("Energy" (1; #2), 58.0),
#   ("RootMeanSquared" (1; #13), 56.0),
#   ("TotalEnergy" (1; #15), 56.0),
#   ("Mean" (1; #7), 51.0),
#   ("Median" (1; #9), 51.0),
#   ("10Percentile" (1; #0), 16.0),
#   ("Maximum" (1; #6), 7.0),
#   ("90Percentile" (1; #1), 4.0),
#   ("Uniformity" (1; #16), 1.0)],
#  'SUM_SCORE': [("Median" (1; #9), 39931.93392425),
#   ("Energy" (1; #2), 39663.2386965407),
#   ("TotalEnergy" (1; #15), 38757.30720156747),
#   ("RootMeanSquared" (1; #13), 38652.41974005195),
#   ("Mean" (1; #7), 35416.28031531317),
#   ("10Percentile" (1; #0), 16252.705336281551),
#   ("Maximum" (1; #6), 7997.221782907488),
#   ("Uniformity" (1; #16), 6417.8137948034155),
#   ("90Percentile" (1; #1), 5984.016186399193),
#   ("InterquartileRange" (1; #4), 5434.737924936549),
#   ("Entropy" (1; #3), 4707.340474336031),
#   ("RobustMeanAbsoluteDeviation" (1; #12), 4681.617825838273),
#   ("Skewness" (1; #14), 3515.95769055952),
#   ("Range" (1; #11), 3170.6351013894537),
#   ("Kurtosis" (1; #5), 3055.0801406974724),
#   ("Minimum" (1; #10), 2859.8817158855795),
#   ("MeanAbsoluteDeviation" (1; #8), 2591.849180189539),
#   ("Variance" (1; #17), 2368.056149515205)],
#  'NUM_NODES': [("Median" (1; #9), 778.0),
#   ("Maximum" (1; #6), 620.0),
#   ("Mean" (1; #7), 605.0),
#   ("Uniformity" (1; #16), 592.0),
#   ("Entropy" (1; #3), 547.0),
#   ("RootMeanSquared" (1; #13), 537.0),
#   ("InterquartileRange" (1; #4), 518.0),
#   ("TotalEnergy" (1; #15), 513.0),
#   ("10Percentile" (1; #0), 508.0),
#   ("Energy" (1; #2), 495.0),
#   ("Skewness" (1; #14), 476.0),
#   ("RobustMeanAbsoluteDeviation" (1; #12), 470.0),
#   ("90Percentile" (1; #1), 430.0),
#   ("Range" (1; #11), 424.0),
#   ("Kurtosis" (1; #5), 399.0),
#   ("Minimum" (1; #10), 360.0),
#   ("MeanAbsoluteDeviation" (1; #8), 346.0),
#   ("Variance" (1; #17), 301.0)]}

# %%
# Model self evaluation
model.make_inspector().evaluation()
# Out:
# Evaluation(num_examples=1336, accuracy=0.8904947422721005, loss=0.5017851803121235, rmse=None, ndcg=None, aucs=None, auuc=None, qini=None)

# %%
logs = model.make_inspector().training_logs()

plt.figure(figsize=(12, 4))
plt.subplot(1, 2, 1)
plt.plot([log.num_trees for log in logs], [log.evaluation.accuracy for log in logs])
plt.xlabel("Number of trees")
plt.ylabel("Accuracy (out-of-bag)")
plt.subplot(1, 2, 2)
plt.plot([log.num_trees for log in logs], [log.evaluation.loss for log in logs])
plt.xlabel("Number of trees")
plt.ylabel("Logloss (out-of-bag)")
plt.show()

# %% [markdown]
# Calculate the score of our hold-out validation dataset

# %%
predictions = model.predict(val_ds)
y_true      = validation_data["label"]

from sklearn.metrics import roc_auc_score
ROC_AUC = roc_auc_score(y_true, predictions)
print("The ROC AUC score is %.5f" % ROC_AUC )
# Out:
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 79ms/step
# The ROC AUC score is 0.95877

# %%
# Compute binary classification metrics with sklearn
import numpy as np
from sklearn.metrics import (
    accuracy_score,
    precision_score,
    recall_score,
    f1_score,
    roc_auc_score,
    average_precision_score,
    confusion_matrix,
    classification_report,
    matthews_corrcoef,
    log_loss,
    brier_score_loss,
)

# Get predictions (probabilities or class labels)
preds = model.predict(test_ds)
# If model outputs probabilities, convert to labels by threshold 0.5
if preds.ndim == 2:
    # For TFDF classification, preds may be class probabilities with shape (N, 2)
    if preds.shape[1] == 2:
        pos_probs = preds[:, 1]
    else:
        # If single-probability column (positive class)
        pos_probs = preds[:, -1]
    y_pred = (pos_probs >= 0.5).astype(int)
else:
    # Already class labels
    y_pred = preds.astype(int)
    pos_probs = None

# Ground truth labels (must be 0/1 integers)
y_true = test_data["label"].astype(int).to_numpy()

# Core metrics
metrics = {}
metrics["accuracy"] = accuracy_score(y_true, y_pred)
metrics["precision"] = precision_score(y_true, y_pred, zero_division=0)
metrics["recall"] = recall_score(y_true, y_pred, zero_division=0)
metrics["f1"] = f1_score(y_true, y_pred, zero_division=0)
metrics["mcc"] = matthews_corrcoef(y_true, y_pred)

# Probabilistic metrics (only if we have probabilities)
if pos_probs is not None:
    metrics["roc_auc"] = roc_auc_score(y_true, pos_probs)
    metrics["pr_auc"] = average_precision_score(y_true, pos_probs)
    metrics["log_loss"] = log_loss(y_true, pos_probs, labels=[0,1])
    metrics["brier_score"] = brier_score_loss(y_true, pos_probs)

# Confusion matrix and detailed report
cm = confusion_matrix(y_true, y_pred, labels=[0,1])
report = classification_report(y_true, y_pred, digits=4)

print("Sklearn binary metrics:")
for k, v in metrics.items():
    print(f"{k}: {v:.4f}")
print("\nConfusion matrix:\n", cm)
print("\nClassification report:\n", report)
# Out:
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 87ms/step
# Sklearn binary metrics:
# accuracy: 0.9372
# precision: 0.8182
# recall: 0.7627
# f1: 0.7895
# mcc: 0.7532
# roc_auc: 0.9715
# pr_auc: 0.9001
# log_loss: 0.1426
# brier_score: 0.0438
#
# Confusion matrix:
#  [[313  10]
#  [ 14  45]]
#
# Classification report:
#                precision    recall  f1-score   support
#
#            0     0.9572    0.9690    0.9631       323
#            1     0.8182    0.7627    0.7895        59
#
#     accuracy                         0.9372       382
#    macro avg     0.8877    0.8659    0.8763       382
# weighted avg     0.9357    0.9372    0.9363       382
