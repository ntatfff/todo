# %%
# Import packages and modules
import numpy  as np
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow_decision_forests as tfdf

from sklearn.model_selection import train_test_split
# Out:
# 2026-08-15 05:01:05.317905: I tensorflow/core/util/port.cc:113] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2026-08-15 05:01:05.669868: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2026-08-15 05:01:10.394270: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
# Check the version of TensorFlow Decision Forests
print("Found TensorFlow Decision Forests v" + tfdf.__version__)
# Out:
# Found TensorFlow Decision Forests v1.9.1

# %%
datasetPath = 'dataset/firstorder/kernel5/dataset.csv'

# %%
# Parameters
datasetPath = "dataset/ngtdm/kernel4/1.dataset.csv"

# %%
# train/validation/test = 70/10/20
dataset = pd.read_csv(datasetPath)

train_data, temp_data = train_test_split(dataset, test_size=0.3, random_state=42)
validation_data, test_data = train_test_split(temp_data, test_size=2/3, random_state=42)

# %%
from sklearn.utils.class_weight import compute_class_weight

# tinh class weight tren tap train
classes = np.array([0, 1])
weights = compute_class_weight(class_weight="balanced", classes=classes, y=train_data["label"])
class_weight = {0: weights[0], 1: weights[1]}

# gan sample_weight cho tung dong
train_data["sample_weight"] = train_data["label"].map(class_weight)
validation_data["sample_weight"] = validation_data["label"].map(class_weight)
test_data["sample_weight"] = test_data["label"].map(class_weight)

# Convert the dataset into a TensorFlow dataset.
train_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    train_data, label="label", weight="sample_weight"
)         
val_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    validation_data, label="label", weight="sample_weight"
)
test_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    test_data, label="label", weight="sample_weight"
)
# Out:
# 2026-08-15 05:01:23.930904: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:984] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2026-08-15 05:01:23.932003: W tensorflow/core/common_runtime/gpu/gpu_device.cc:2251] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...

# %%
import keras

# %%
# %%time

# Train a Gradient Boosted Trees model.
model = tfdf.keras.GradientBoostedTreesModel()

# Add evaluation metrics
model.compile(
    metrics=["accuracy"]
)
model.fit(x=train_ds)

# # Train a Gradient Boosted Trees model.
# model = tfdf.keras.GradientBoostedTreesModel(num_trees=1500)
# model.fit(train_ds)
# Out:
# Use /tmp/tmpn63ug5gv as temporary training directory
# Reading training dataset...
# [WARNING 26-08-15 05:01:24.0528 UTC gradient_boosted_trees.cc:1840] "goss_alpha" set but "sampling_method" not equal to "GOSS".
# [WARNING 26-08-15 05:01:24.0530 UTC gradient_boosted_trees.cc:1851] "goss_beta" set but "sampling_method" not equal to "GOSS".
# [WARNING 26-08-15 05:01:24.0531 UTC gradient_boosted_trees.cc:1865] "selective_gradient_boosting_ratio" set but "sampling_method" not equal to "SELGB".
# Training dataset read in 0:00:02.501178. Found 1554 examples.
# Training model...
# Model trained in 0:00:00.853018
# Compiling model...
# [INFO 26-08-15 05:01:27.4281 UTC kernel.cc:1233] Loading model from path /tmp/tmpn63ug5gv/model/ with prefix bcf3f6611ddb4b94
# [INFO 26-08-15 05:01:27.4419 UTC quick_scorer_extended.cc:911] The binary was compiled without AVX2 support, but your CPU supports it. Enable it for faster model inference.
# [INFO 26-08-15 05:01:27.4430 UTC abstract_model.cc:1362] Engine "GradientBoostedTreesQuickScorerExtended" built
# [INFO 26-08-15 05:01:27.4430 UTC kernel.cc:1061] Use fast generic engine
# Model compiled.
# CPU times: user 6.29 s, sys: 751 ms, total: 7.05 s
# Wall time: 6.55 s

# %%
# Evaluate the model
evaluate = model.evaluate(val_ds, return_dict=True)
print()

for name, value in evaluate.items():
    print(f"{name}: {value:.4f}")
# Out:
# WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 1/1 [==============================] - ETA: 0s - loss: 0.0000e+00 - accuracy: 0.9865
# 1/1 [==============================] - 3s 3s/step - loss: 0.0000e+00 - accuracy: 0.9865
# loss: 0.0000
# accuracy: 0.9865

# %%
# Model Summary
model.summary()
# Out:
# Model: "gradient_boosted_trees_model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
# =================================================================
# Total params: 1 (1.00 Byte)
# Trainable params: 0 (0.00 Byte)
# Non-trainable params: 1 (1.00 Byte)
# _________________________________________________________________
# Type: "GRADIENT_BOOSTED_TREES"
# Task: CLASSIFICATION
# Label: "__LABEL"
#
# Input Features (5):
# 	Busyness
# 	Coarseness
# 	Complexity
# 	Contrast
# 	Strength
#
# Trained with weights
#
# Variable Importance: INV_MEAN_MIN_DEPTH:
#     1.   "Busyness"  0.385643 ################
#     2.   "Contrast"  0.272288 ##
#     3. "Coarseness"  0.262061 #
#     4. "Complexity"  0.257545
#     5.   "Strength"  0.252277
#
# Variable Importance: NUM_AS_ROOT:
#     1.   "Busyness" 132.000000 ################
#     2.   "Contrast" 52.000000 #####
#     3. "Complexity" 51.000000 ####
#     4. "Coarseness" 50.000000 ####
#     5.   "Strength" 15.000000
#
# Variable Importance: NUM_NODES:
#     1.   "Busyness" 1644.000000 ################
#     2. "Coarseness" 924.000000 ##
#     3.   "Contrast" 902.000000 ##
#     4. "Complexity" 878.000000 #
#     5.   "Strength" 779.000000
#
# Variable Importance: SUM_SCORE:
#     1.   "Busyness" 1563.286405 ################
#     2. "Complexity" 99.991170
#     3.   "Strength" 99.135437
#     4. "Coarseness" 89.745926
#     5.   "Contrast" 55.368926
#
#
#
# Loss: BINOMIAL_LOG_LIKELIHOOD
# Validation loss value: 0.0156384
# Number of trees per iteration: 1
# Node format: NOT_SET
# Number of trees: 300
# Total number of nodes: 10554
#
# Number of nodes by tree:
# Count: 300 Average: 35.18 StdDev: 6.32094
# Min: 19 Max: 49 Ignored: 0
# ----------------------------------------------
# [ 19, 20)  1   0.33%   0.33%
# [ 20, 22)  2   0.67%   1.00% #
# [ 22, 23)  0   0.00%   1.00%
# [ 23, 25)  9   3.00%   4.00% ##
# [ 25, 26) 12   4.00%   8.00% ###
# [ 26, 28) 19   6.33%  14.33% #####
# [ 28, 29)  0   0.00%  14.33%
# [ 29, 31) 24   8.00%  22.33% ######
# [ 31, 32) 29   9.67%  32.00% #######
# [ 32, 34) 28   9.33%  41.33% #######
# [ 34, 36) 39  13.00%  54.33% ##########
# [ 36, 37)  0   0.00%  54.33%
# [ 37, 39) 35  11.67%  66.00% #########
# [ 39, 40) 29   9.67%  75.67% #######
# [ 40, 42) 32  10.67%  86.33% ########
# [ 42, 43)  0   0.00%  86.33%
# [ 43, 45) 17   5.67%  92.00% ####
# [ 45, 46) 13   4.33%  96.33% ###
# [ 46, 48)  2   0.67%  97.00% #
# [ 48, 49]  9   3.00% 100.00% ##
#
# Depth by leafs:
# Count: 5427 Average: 4.49254 StdDev: 0.832194
# Min: 1 Max: 5 Ignored: 0
# ----------------------------------------------
# [ 1, 2)    6   0.11%   0.11%
# [ 2, 3)  188   3.46%   3.57% #
# [ 3, 4)  601  11.07%  14.65% ##
# [ 4, 5)  964  17.76%  32.41% ###
# [ 5, 5] 3668  67.59% 100.00% ##########
#
# Number of training obs by leaf:
# Count: 5427 Average: 78.7728 StdDev: 202.725
# Min: 5 Max: 1293 Ignored: 0
# ----------------------------------------------
# [    5,   69) 4513  83.16%  83.16% ##########
# [   69,  133)  181   3.34%  86.49%
# [  133,  198)  153   2.82%  89.31%
# [  198,  262)  131   2.41%  91.73%
# [  262,  327)   45   0.83%  92.56%
# [  327,  391)   57   1.05%  93.61%
# [  391,  456)   62   1.14%  94.75%
# [  456,  520)   41   0.76%  95.50%
# [  520,  585)   19   0.35%  95.85%
# [  585,  649)    9   0.17%  96.02%
# [  649,  713)   16   0.29%  96.31%
# [  713,  778)   11   0.20%  96.52%
# [  778,  842)   17   0.31%  96.83%
# [  842,  907)   41   0.76%  97.59%
# [  907,  971)   49   0.90%  98.49%
# [  971, 1036)   27   0.50%  98.99%
# [ 1036, 1100)   21   0.39%  99.37%
# [ 1100, 1165)    3   0.06%  99.43%
# [ 1165, 1229)   13   0.24%  99.67%
# [ 1229, 1293]   18   0.33% 100.00%
#
# Attribute in nodes:
# 	1644 : Busyness [NUMERICAL]
# 	924 : Coarseness [NUMERICAL]
# 	902 : Contrast [NUMERICAL]
# 	878 : Complexity [NUMERICAL]
# 	779 : Strength [NUMERICAL]
#
# Attribute in nodes with depth <= 0:
# 	132 : Busyness [NUMERICAL]
# 	52 : Contrast [NUMERICAL]
# 	51 : Complexity [NUMERICAL]
# 	50 : Coarseness [NUMERICAL]
# 	15 : Strength [NUMERICAL]
#
# Attribute in nodes with depth <= 1:
# 	286 : Busyness [NUMERICAL]
# 	166 : Complexity [NUMERICAL]
# 	165 : Contrast [NUMERICAL]
# 	150 : Coarseness [NUMERICAL]
# 	127 : Strength [NUMERICAL]
#
# Attribute in nodes with depth <= 2:
# 	612 : Busyness [NUMERICAL]
# 	370 : Contrast [NUMERICAL]
# 	348 : Complexity [NUMERICAL]
# 	290 : Coarseness [NUMERICAL]
# 	274 : Strength [NUMERICAL]
#
# Attribute in nodes with depth <= 3:
# 	988 : Busyness [NUMERICAL]
# 	615 : Complexity [NUMERICAL]
# 	599 : Coarseness [NUMERICAL]
# 	594 : Contrast [NUMERICAL]
# 	497 : Strength [NUMERICAL]
#
# Attribute in nodes with depth <= 5:
# 	1644 : Busyness [NUMERICAL]
# 	924 : Coarseness [NUMERICAL]
# 	902 : Contrast [NUMERICAL]
# 	878 : Complexity [NUMERICAL]
# 	779 : Strength [NUMERICAL]
#
# Condition type in nodes:
# 	5127 : HigherCondition
# Condition type in nodes with depth <= 0:
# 	300 : HigherCondition
# Condition type in nodes with depth <= 1:
# 	894 : HigherCondition
# Condition type in nodes with depth <= 2:
# 	1894 : HigherCondition
# Condition type in nodes with depth <= 3:
# 	3293 : HigherCondition
# Condition type in nodes with depth <= 5:
# 	5127 : HigherCondition
#
# Training logs:
# Number of iteration to final model: 300
# 	Iter:1 train-loss:1.209620 valid-loss:1.235268  train-accuracy:0.979908 valid-accuracy:0.907200
# 	Iter:2 train-loss:1.064815 valid-loss:1.113725  train-accuracy:0.982141 valid-accuracy:0.907200
# 	Iter:3 train-loss:0.944596 valid-loss:0.997453  train-accuracy:0.981025 valid-accuracy:0.907200
# 	Iter:4 train-loss:0.841357 valid-loss:0.889744  train-accuracy:0.982141 valid-accuracy:0.907200
# 	Iter:5 train-loss:0.752185 valid-loss:0.797580  train-accuracy:0.984745 valid-accuracy:0.978100
# 	Iter:6 train-loss:0.676170 valid-loss:0.720960  train-accuracy:0.983257 valid-accuracy:0.978100
# 	Iter:16 train-loss:0.279404 valid-loss:0.316616  train-accuracy:0.986978 valid-accuracy:0.978100
# 	Iter:26 train-loss:0.142734 valid-loss:0.206256  train-accuracy:0.990698 valid-accuracy:0.978100
# 	Iter:36 train-loss:0.080451 valid-loss:0.144388  train-accuracy:0.992187 valid-accuracy:0.982480
# 	Iter:46 train-loss:0.049272 valid-loss:0.104783  train-accuracy:0.995163 valid-accuracy:0.986860
# 	Iter:56 train-loss:0.032640 valid-loss:0.090076  train-accuracy:0.998512 valid-accuracy:0.986860
# 	Iter:66 train-loss:0.023316 valid-loss:0.078538  train-accuracy:1.000000 valid-accuracy:0.986860
# 	Iter:76 train-loss:0.016651 valid-loss:0.071382  train-accuracy:1.000000 valid-accuracy:0.986860
# 	Iter:86 train-loss:0.012529 valid-loss:0.071436  train-accuracy:1.000000 valid-accuracy:0.991240
# 	Iter:96 train-loss:0.008665 valid-loss:0.064885  train-accuracy:1.000000 valid-accuracy:0.991240
# 	Iter:106 train-loss:0.006621 valid-loss:0.064221  train-accuracy:1.000000 valid-accuracy:0.991240
# 	Iter:116 train-loss:0.004982 valid-loss:0.057170  train-accuracy:1.000000 valid-accuracy:0.991240
# 	Iter:126 train-loss:0.003711 valid-loss:0.047470  train-accuracy:1.000000 valid-accuracy:0.991240
# 	Iter:136 train-loss:0.002669 valid-loss:0.039001  train-accuracy:1.000000 valid-accuracy:0.991240
# 	Iter:146 train-loss:0.001808 valid-loss:0.035766  train-accuracy:1.000000 valid-accuracy:0.995620
# 	Iter:156 train-loss:0.001323 valid-loss:0.035712  train-accuracy:1.000000 valid-accuracy:0.995620
# 	Iter:166 train-loss:0.000983 valid-loss:0.029494  train-accuracy:1.000000 valid-accuracy:0.995620
# 	Iter:176 train-loss:0.000677 valid-loss:0.028401  train-accuracy:1.000000 valid-accuracy:0.995620
# 	Iter:186 train-loss:0.000493 valid-loss:0.025674  train-accuracy:1.000000 valid-accuracy:0.995620
# 	Iter:196 train-loss:0.000360 valid-loss:0.023103  train-accuracy:1.000000 valid-accuracy:0.995620
# 	Iter:206 train-loss:0.000262 valid-loss:0.021199  train-accuracy:1.000000 valid-accuracy:0.995620
# 	Iter:216 train-loss:0.000191 valid-loss:0.020232  train-accuracy:1.000000 valid-accuracy:0.995620
# 	Iter:226 train-loss:0.000140 valid-loss:0.020890  train-accuracy:1.000000 valid-accuracy:0.995620
# 	Iter:236 train-loss:0.000105 valid-loss:0.019321  train-accuracy:1.000000 valid-accuracy:0.995620
# 	Iter:246 train-loss:0.000083 valid-loss:0.017871  train-accuracy:1.000000 valid-accuracy:0.995620
# 	Iter:256 train-loss:0.000063 valid-loss:0.018225  train-accuracy:1.000000 valid-accuracy:0.995620
# 	Iter:266 train-loss:0.000048 valid-loss:0.017510  train-accuracy:1.000000 valid-accuracy:0.995620
# 	Iter:276 train-loss:0.000037 valid-loss:0.018691  train-accuracy:1.000000 valid-accuracy:0.995620
# 	Iter:286 train-loss:0.000030 valid-loss:0.016936  train-accuracy:1.000000 valid-accuracy:0.995620
# 	Iter:296 train-loss:0.000025 valid-loss:0.016198  train-accuracy:1.000000 valid-accuracy:0.995620

# %%
# Model features
model.make_inspector().features()
# Out:
# ["Busyness" (1; #0),
#  "Coarseness" (1; #1),
#  "Complexity" (1; #2),
#  "Contrast" (1; #3),
#  "Strength" (1; #4)]

# %%
# Feature importance
model.make_inspector().variable_importances()
# Out:
# {'INV_MEAN_MIN_DEPTH': [("Busyness" (1; #0), 0.3856432889587357),
#   ("Contrast" (1; #3), 0.27228803381621003),
#   ("Coarseness" (1; #1), 0.2620614670293169),
#   ("Complexity" (1; #2), 0.25754537281655776),
#   ("Strength" (1; #4), 0.25227697422803796)],
#  'NUM_AS_ROOT': [("Busyness" (1; #0), 132.0),
#   ("Contrast" (1; #3), 52.0),
#   ("Complexity" (1; #2), 51.0),
#   ("Coarseness" (1; #1), 50.0),
#   ("Strength" (1; #4), 15.0)],
#  'SUM_SCORE': [("Busyness" (1; #0), 1563.286405064892),
#   ("Complexity" (1; #2), 99.99117042645851),
#   ("Strength" (1; #4), 99.13543725894749),
#   ("Coarseness" (1; #1), 89.7459264630719),
#   ("Contrast" (1; #3), 55.368926121453775)],
#  'NUM_NODES': [("Busyness" (1; #0), 1644.0),
#   ("Coarseness" (1; #1), 924.0),
#   ("Contrast" (1; #3), 902.0),
#   ("Complexity" (1; #2), 878.0),
#   ("Strength" (1; #4), 779.0)]}

# %%
# Model self evaluation
model.make_inspector().evaluation()
# Out:
# Evaluation(num_examples=None, accuracy=0.9956200122833252, loss=0.0156384389847517, rmse=None, ndcg=None, aucs=None, auuc=None, qini=None)

# %%
logs = model.make_inspector().training_logs()

plt.figure(figsize=(12, 4))
plt.subplot(1, 2, 1)
plt.plot([log.num_trees for log in logs], [log.evaluation.accuracy for log in logs])
plt.xlabel("Number of trees")
plt.ylabel("Accuracy (out-of-bag)")
plt.subplot(1, 2, 2)
plt.plot([log.num_trees for log in logs], [log.evaluation.loss for log in logs])
plt.xlabel("Number of trees")
plt.ylabel("Logloss (out-of-bag)")
plt.show()

# %% [markdown]
# Calculate the score of our hold-out validation dataset

# %%
predictions = model.predict(val_ds)
y_true      = validation_data["label"]

from sklearn.metrics import roc_auc_score
ROC_AUC = roc_auc_score(y_true, predictions)
print("The ROC AUC score is %.5f" % ROC_AUC )
# Out:
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 52ms/step
# The ROC AUC score is 0.99517

# %%
# Compute binary classification metrics with sklearn
import numpy as np
from sklearn.metrics import (
    accuracy_score,
    precision_score,
    recall_score,
    f1_score,
    roc_auc_score,
    average_precision_score,
    confusion_matrix,
    classification_report,
    matthews_corrcoef,
    log_loss,
    brier_score_loss,
)

# Get predictions (probabilities or class labels)
preds = model.predict(test_ds)
# If model outputs probabilities, convert to labels by threshold 0.5
if preds.ndim == 2:
    # For TFDF classification, preds may be class probabilities with shape (N, 2)
    if preds.shape[1] == 2:
        pos_probs = preds[:, 1]
    else:
        # If single-probability column (positive class)
        pos_probs = preds[:, -1]
    y_pred = (pos_probs >= 0.5).astype(int)
else:
    # Already class labels
    y_pred = preds.astype(int)
    pos_probs = None

# Ground truth labels (must be 0/1 integers)
y_true = test_data["label"].astype(int).to_numpy()

# Core metrics
metrics = {}
metrics["accuracy"] = accuracy_score(y_true, y_pred)
metrics["precision"] = precision_score(y_true, y_pred, zero_division=0)
metrics["recall"] = recall_score(y_true, y_pred, zero_division=0)
metrics["f1"] = f1_score(y_true, y_pred, zero_division=0)
metrics["mcc"] = matthews_corrcoef(y_true, y_pred)

# Probabilistic metrics (only if we have probabilities)
if pos_probs is not None:
    metrics["roc_auc"] = roc_auc_score(y_true, pos_probs)
    metrics["pr_auc"] = average_precision_score(y_true, pos_probs)
    metrics["log_loss"] = log_loss(y_true, pos_probs, labels=[0,1])
    metrics["brier_score"] = brier_score_loss(y_true, pos_probs)

# Confusion matrix and detailed report
cm = confusion_matrix(y_true, y_pred, labels=[0,1])
report = classification_report(y_true, y_pred, digits=4)

print("Sklearn binary metrics:")
for k, v in metrics.items():
    print(f"{k}: {v:.4f}")
print("\nConfusion matrix:\n", cm)
print("\nClassification report:\n", report)
# Out:
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 68ms/step
# Sklearn binary metrics:
# accuracy: 0.9910
# precision: 0.9286
# recall: 0.9286
# f1: 0.9286
# mcc: 0.9238
# roc_auc: 0.9986
# pr_auc: 0.9825
# log_loss: 0.0365
# brier_score: 0.0087
#
# Confusion matrix:
#  [[414   2]
#  [  2  26]]
#
# Classification report:
#                precision    recall  f1-score   support
#
#            0     0.9952    0.9952    0.9952       416
#            1     0.9286    0.9286    0.9286        28
#
#     accuracy                         0.9910       444
#    macro avg     0.9619    0.9619    0.9619       444
# weighted avg     0.9910    0.9910    0.9910       444
