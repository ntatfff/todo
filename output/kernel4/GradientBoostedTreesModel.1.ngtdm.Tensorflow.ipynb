# %%
# Import packages and modules
import numpy  as np
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow_decision_forests as tfdf

from sklearn.model_selection import train_test_split
# Out:
# 2026-08-10 17:13:27.334236: I tensorflow/core/util/port.cc:113] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2026-08-10 17:13:27.741002: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2026-08-10 17:13:32.437588: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
# Check the version of TensorFlow Decision Forests
print("Found TensorFlow Decision Forests v" + tfdf.__version__)
# Out:
# Found TensorFlow Decision Forests v1.9.1

# %%
datasetPath = 'dataset/firstorder/kernel5-radius5/dataset.csv'

# %%
# Parameters
datasetPath = "dataset/ngtdm/kernel4-radius4/dataset.1p.csv"

# %%
# train/validation/test = 70/10/20
dataset = pd.read_csv(datasetPath)

train_data, temp_data = train_test_split(dataset, test_size=0.3, random_state=42)
validation_data, test_data = train_test_split(temp_data, test_size=2/3, random_state=42)

# %%
from sklearn.utils.class_weight import compute_class_weight

# tinh class weight tren tap train
classes = np.array([0, 1])
weights = compute_class_weight(class_weight="balanced", classes=classes, y=train_data["label"])
class_weight = {0: weights[0], 1: weights[1]}

# gan sample_weight cho tung dong
train_data["sample_weight"] = train_data["label"].map(class_weight)
validation_data["sample_weight"] = validation_data["label"].map(class_weight)
test_data["sample_weight"] = test_data["label"].map(class_weight)

# Convert the dataset into a TensorFlow dataset.
train_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    train_data, label="label", weight="sample_weight"
)         
val_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    validation_data, label="label", weight="sample_weight"
)
test_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    test_data, label="label", weight="sample_weight"
)
# Out:
# 2026-08-10 17:13:46.775603: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:984] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2026-08-10 17:13:46.777791: W tensorflow/core/common_runtime/gpu/gpu_device.cc:2251] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...

# %%
import keras

# %%
# %%time

# Train a Gradient Boosted Trees model.
model = tfdf.keras.GradientBoostedTreesModel()

# Add evaluation metrics
model.compile(
    metrics=["accuracy"]
)
model.fit(x=train_ds)

# # Train a Gradient Boosted Trees model.
# model = tfdf.keras.GradientBoostedTreesModel(num_trees=1500)
# model.fit(train_ds)
# Out:
# Use /tmp/tmppu2wajpy as temporary training directory
# Reading training dataset...
# [WARNING 26-08-10 17:13:47.4701 UTC gradient_boosted_trees.cc:1840] "goss_alpha" set but "sampling_method" not equal to "GOSS".
# [WARNING 26-08-10 17:13:47.4703 UTC gradient_boosted_trees.cc:1851] "goss_beta" set but "sampling_method" not equal to "GOSS".
# [WARNING 26-08-10 17:13:47.4703 UTC gradient_boosted_trees.cc:1865] "selective_gradient_boosting_ratio" set but "sampling_method" not equal to "SELGB".
# Training dataset read in 0:00:03.411926. Found 1542 examples.
# Training model...
# Model trained in 0:00:01.330351
# Compiling model...
# [INFO 26-08-10 17:13:52.2426 UTC kernel.cc:1233] Loading model from path /tmp/tmppu2wajpy/model/ with prefix fe59d0540ee045f8
# [INFO 26-08-10 17:13:52.2450 UTC quick_scorer_extended.cc:911] The binary was compiled without AVX2 support, but your CPU supports it. Enable it for faster model inference.
# [INFO 26-08-10 17:13:52.2451 UTC abstract_model.cc:1362] Engine "GradientBoostedTreesQuickScorerExtended" built
# [INFO 26-08-10 17:13:52.2451 UTC kernel.cc:1061] Use fast generic engine
# Model compiled.
# CPU times: user 6.12 s, sys: 416 ms, total: 6.54 s
# Wall time: 8.2 s

# %%
# Evaluate the model
evaluate = model.evaluate(val_ds, return_dict=True)
print()

for name, value in evaluate.items():
    print(f"{name}: {value:.4f}")
# Out:
# WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 1/1 [==============================] - ETA: 0s - loss: 0.0000e+00 - accuracy: 1.0000
# 1/1 [==============================] - 3s 3s/step - loss: 0.0000e+00 - accuracy: 1.0000
# loss: 0.0000
# accuracy: 1.0000

# %%
# Model Summary
model.summary()
# Out:
# Model: "gradient_boosted_trees_model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
# =================================================================
# Total params: 1 (1.00 Byte)
# Trainable params: 0 (0.00 Byte)
# Non-trainable params: 1 (1.00 Byte)
# _________________________________________________________________
# Type: "GRADIENT_BOOSTED_TREES"
# Task: CLASSIFICATION
# Label: "__LABEL"
#
# Input Features (23):
# 	10Percentile
# 	90Percentile
# 	Busyness
# 	Coarseness
# 	Complexity
# 	Contrast
# 	Energy
# 	Entropy
# 	InterquartileRange
# 	Kurtosis
# 	Maximum
# 	Mean
# 	MeanAbsoluteDeviation
# 	Median
# 	Minimum
# 	Range
# 	RobustMeanAbsoluteDeviation
# 	RootMeanSquared
# 	Skewness
# 	Strength
# 	TotalEnergy
# 	Uniformity
# 	Variance
#
# Trained with weights
#
# Variable Importance: INV_MEAN_MIN_DEPTH:
#     1.                    "Busyness"  1.000000 ################
#     2.                    "Contrast"  0.259945
#     3.                  "Complexity"  0.259038
#     4.                  "Coarseness"  0.256677
#     5.                    "Strength"  0.255755
#     6.                  "Uniformity"  0.245849
#     7.                     "Maximum"  0.243865
#     8.                    "Variance"  0.243084
#     9.                      "Energy"  0.242735
#    10.          "InterquartileRange"  0.242457
#    11.                        "Mean"  0.242439
#    12.                "10Percentile"  0.242359
#    13.                "90Percentile"  0.242359
#    14. "RobustMeanAbsoluteDeviation"  0.242177
#    15.                     "Minimum"  0.242146
#    16.       "MeanAbsoluteDeviation"  0.242076
#    17.                 "TotalEnergy"  0.241989
#    18.                       "Range"  0.241746
#    19.                      "Median"  0.241682
#    20.                    "Kurtosis"  0.241561
#    21.                    "Skewness"  0.241302
#    22.             "RootMeanSquared"  0.241044
#    23.                     "Entropy"  0.240966
#
# Variable Importance: NUM_AS_ROOT:
#     1. "Busyness" 45.000000
#
# Variable Importance: NUM_NODES:
#     1.                    "Busyness" 117.000000 ################
#     2.                    "Contrast" 34.000000 ####
#     3.                  "Coarseness" 32.000000 ####
#     4.                  "Complexity" 31.000000 ####
#     5.                    "Strength" 29.000000 ###
#     6.                  "Uniformity"  8.000000
#     7.                    "Variance"  7.000000
#     8.                     "Maximum"  6.000000
#     9.                      "Energy"  5.000000
#    10.          "InterquartileRange"  5.000000
#    11.       "MeanAbsoluteDeviation"  5.000000
#    12.                      "Median"  5.000000
#    13.                       "Range"  5.000000
#    14. "RobustMeanAbsoluteDeviation"  5.000000
#    15.                        "Mean"  4.000000
#    16.                     "Minimum"  4.000000
#    17.                "10Percentile"  3.000000
#    18.                    "Kurtosis"  3.000000
#    19.                 "TotalEnergy"  3.000000
#    20.                "90Percentile"  2.000000
#    21.                     "Entropy"  2.000000
#    22.             "RootMeanSquared"  2.000000
#    23.                    "Skewness"  2.000000
#
# Variable Importance: SUM_SCORE:
#     1.                    "Busyness" 1910.676987 ################
#     2.                  "Coarseness"  0.000000
#     3.                  "Complexity"  0.000000
#     4.                     "Maximum"  0.000000
#     5.                      "Energy"  0.000000
#     6.                       "Range"  0.000000
#     7.                    "Strength"  0.000000
#     8.                "90Percentile"  0.000000
#     9. "RobustMeanAbsoluteDeviation"  0.000000
#    10.                "10Percentile"  0.000000
#    11.                    "Contrast"  0.000000
#    12.                    "Kurtosis"  0.000000
#    13.                 "TotalEnergy"  0.000000
#    14.                     "Entropy"  0.000000
#    15.          "InterquartileRange"  0.000000
#    16.                      "Median"  0.000000
#    17.                    "Variance"  0.000000
#    18.                  "Uniformity"  0.000000
#    19.                        "Mean"  0.000000
#    20.       "MeanAbsoluteDeviation"  0.000000
#    21.             "RootMeanSquared"  0.000000
#    22.                     "Minimum"  0.000000
#    23.                    "Skewness"  0.000000
#
#
#
# Loss: BINOMIAL_LOG_LIKELIHOOD
# Validation loss value: 0.0697404
# Number of trees per iteration: 1
# Node format: NOT_SET
# Number of trees: 45
# Total number of nodes: 683
#
# Number of nodes by tree:
# Count: 45 Average: 15.1778 StdDev: 2.69393
# Min: 9 Max: 21 Ignored: 0
# ----------------------------------------------
# [  9, 10)  1   2.22%   2.22% #
# [ 10, 11)  0   0.00%   2.22%
# [ 11, 12)  3   6.67%   8.89% ##
# [ 12, 13)  0   0.00%   8.89%
# [ 13, 14) 12  26.67%  35.56% #########
# [ 14, 15)  0   0.00%  35.56%
# [ 15, 16) 14  31.11%  66.67% ##########
# [ 16, 17)  0   0.00%  66.67%
# [ 17, 18)  7  15.56%  82.22% #####
# [ 18, 19)  0   0.00%  82.22%
# [ 19, 20)  6  13.33%  95.56% ####
# [ 20, 21)  0   0.00%  95.56%
# [ 21, 21]  2   4.44% 100.00% #
#
# Depth by leafs:
# Count: 364 Average: 3.20879 StdDev: 0.756169
# Min: 1 Max: 5 Ignored: 0
# ----------------------------------------------
# [ 1, 2)   1   0.27%   0.27%
# [ 2, 3)  57  15.66%  15.93% ###
# [ 3, 4) 185  50.82%  66.76% ##########
# [ 4, 5) 107  29.40%  96.15% ######
# [ 5, 5]  14   3.85% 100.00% #
#
# Number of training obs by leaf:
# Count: 364 Average: 175.055 StdDev: 227.224
# Min: 5 Max: 800 Ignored: 0
# ----------------------------------------------
# [   5,  44) 164  45.05%  45.05% ##########
# [  44,  84)  41  11.26%  56.32% ###
# [  84, 124)  12   3.30%  59.62% #
# [ 124, 164)  14   3.85%  63.46% #
# [ 164, 204)  14   3.85%  67.31% #
# [ 204, 243)  28   7.69%  75.00% ##
# [ 243, 283)   6   1.65%  76.65%
# [ 283, 323)  11   3.02%  79.67% #
# [ 323, 363)  21   5.77%  85.44% #
# [ 363, 403)   8   2.20%  87.64%
# [ 403, 442)   1   0.27%  87.91%
# [ 442, 482)   0   0.00%  87.91%
# [ 482, 522)   0   0.00%  87.91%
# [ 522, 562)   0   0.00%  87.91%
# [ 562, 602)   0   0.00%  87.91%
# [ 602, 641)   6   1.65%  89.56%
# [ 641, 681)  11   3.02%  92.58% #
# [ 681, 721)   6   1.65%  94.23%
# [ 721, 761)  10   2.75%  96.98% #
# [ 761, 800]  11   3.02% 100.00% #
#
# Attribute in nodes:
# 	117 : Busyness [NUMERICAL]
# 	34 : Contrast [NUMERICAL]
# 	32 : Coarseness [NUMERICAL]
# 	31 : Complexity [NUMERICAL]
# 	29 : Strength [NUMERICAL]
# 	8 : Uniformity [NUMERICAL]
# 	7 : Variance [NUMERICAL]
# 	6 : Maximum [NUMERICAL]
# 	5 : RobustMeanAbsoluteDeviation [NUMERICAL]
# 	5 : Range [NUMERICAL]
# 	5 : Median [NUMERICAL]
# 	5 : MeanAbsoluteDeviation [NUMERICAL]
# 	5 : InterquartileRange [NUMERICAL]
# 	5 : Energy [NUMERICAL]
# 	4 : Minimum [NUMERICAL]
# 	4 : Mean [NUMERICAL]
# 	3 : TotalEnergy [NUMERICAL]
# 	3 : Kurtosis [NUMERICAL]
# 	3 : 10Percentile [NUMERICAL]
# 	2 : Skewness [NUMERICAL]
# 	2 : RootMeanSquared [NUMERICAL]
# 	2 : Entropy [NUMERICAL]
# 	2 : 90Percentile [NUMERICAL]
#
# Attribute in nodes with depth <= 0:
# 	45 : Busyness [NUMERICAL]
#
# Attribute in nodes with depth <= 1:
# 	101 : Busyness [NUMERICAL]
# 	11 : Complexity [NUMERICAL]
# 	8 : Contrast [NUMERICAL]
# 	7 : Strength [NUMERICAL]
# 	7 : Coarseness [NUMERICAL]
#
# Attribute in nodes with depth <= 2:
# 	112 : Busyness [NUMERICAL]
# 	29 : Contrast [NUMERICAL]
# 	25 : Strength [NUMERICAL]
# 	25 : Complexity [NUMERICAL]
# 	21 : Coarseness [NUMERICAL]
# 	7 : Uniformity [NUMERICAL]
# 	4 : Variance [NUMERICAL]
# 	4 : Energy [NUMERICAL]
# 	3 : Maximum [NUMERICAL]
# 	3 : InterquartileRange [NUMERICAL]
# 	2 : TotalEnergy [NUMERICAL]
# 	2 : RobustMeanAbsoluteDeviation [NUMERICAL]
# 	2 : Range [NUMERICAL]
# 	2 : Minimum [NUMERICAL]
# 	2 : Median [NUMERICAL]
# 	2 : MeanAbsoluteDeviation [NUMERICAL]
# 	2 : Mean [NUMERICAL]
# 	2 : 90Percentile [NUMERICAL]
# 	2 : 10Percentile [NUMERICAL]
# 	1 : Skewness [NUMERICAL]
# 	1 : RootMeanSquared [NUMERICAL]
# 	1 : Kurtosis [NUMERICAL]
# 	1 : Entropy [NUMERICAL]
#
# Attribute in nodes with depth <= 3:
# 	117 : Busyness [NUMERICAL]
# 	33 : Contrast [NUMERICAL]
# 	31 : Coarseness [NUMERICAL]
# 	30 : Complexity [NUMERICAL]
# 	29 : Strength [NUMERICAL]
# 	8 : Uniformity [NUMERICAL]
# 	7 : Variance [NUMERICAL]
# 	6 : Maximum [NUMERICAL]
# 	5 : Median [NUMERICAL]
# 	5 : MeanAbsoluteDeviation [NUMERICAL]
# 	5 : InterquartileRange [NUMERICAL]
# 	5 : Energy [NUMERICAL]
# 	4 : RobustMeanAbsoluteDeviation [NUMERICAL]
# 	4 : Range [NUMERICAL]
# 	4 : Minimum [NUMERICAL]
# 	3 : TotalEnergy [NUMERICAL]
# 	3 : Mean [NUMERICAL]
# 	3 : 10Percentile [NUMERICAL]
# 	2 : Skewness [NUMERICAL]
# 	2 : RootMeanSquared [NUMERICAL]
# 	2 : Kurtosis [NUMERICAL]
# 	2 : Entropy [NUMERICAL]
# 	2 : 90Percentile [NUMERICAL]
#
# Attribute in nodes with depth <= 5:
# 	117 : Busyness [NUMERICAL]
# 	34 : Contrast [NUMERICAL]
# 	32 : Coarseness [NUMERICAL]
# 	31 : Complexity [NUMERICAL]
# 	29 : Strength [NUMERICAL]
# 	8 : Uniformity [NUMERICAL]
# 	7 : Variance [NUMERICAL]
# 	6 : Maximum [NUMERICAL]
# 	5 : RobustMeanAbsoluteDeviation [NUMERICAL]
# 	5 : Range [NUMERICAL]
# 	5 : Median [NUMERICAL]
# 	5 : MeanAbsoluteDeviation [NUMERICAL]
# 	5 : InterquartileRange [NUMERICAL]
# 	5 : Energy [NUMERICAL]
# 	4 : Minimum [NUMERICAL]
# 	4 : Mean [NUMERICAL]
# 	3 : TotalEnergy [NUMERICAL]
# 	3 : Kurtosis [NUMERICAL]
# 	3 : 10Percentile [NUMERICAL]
# 	2 : Skewness [NUMERICAL]
# 	2 : RootMeanSquared [NUMERICAL]
# 	2 : Entropy [NUMERICAL]
# 	2 : 90Percentile [NUMERICAL]
#
# Condition type in nodes:
# 	319 : HigherCondition
# Condition type in nodes with depth <= 0:
# 	45 : HigherCondition
# Condition type in nodes with depth <= 1:
# 	134 : HigherCondition
# Condition type in nodes with depth <= 2:
# 	255 : HigherCondition
# Condition type in nodes with depth <= 3:
# 	312 : HigherCondition
# Condition type in nodes with depth <= 5:
# 	319 : HigherCondition
#
# Training logs:
# Number of iteration to final model: 45
# 	Iter:1 train-loss:1.196200 valid-loss:1.200102  train-accuracy:1.000000 valid-accuracy:0.994363
# 	Iter:2 train-loss:1.040585 valid-loss:1.046270  train-accuracy:1.000000 valid-accuracy:0.994363
# 	Iter:3 train-loss:0.910821 valid-loss:0.918198  train-accuracy:1.000000 valid-accuracy:0.994363
# 	Iter:4 train-loss:0.801136 valid-loss:0.810129  train-accuracy:1.000000 valid-accuracy:0.994363
# 	Iter:5 train-loss:0.707440 valid-loss:0.717985  train-accuracy:1.000000 valid-accuracy:0.994363
# 	Iter:6 train-loss:0.626727 valid-loss:0.638772  train-accuracy:1.000000 valid-accuracy:0.994363
# 	Iter:16 train-loss:0.206067 valid-loss:0.231395  train-accuracy:1.000000 valid-accuracy:0.994363
# 	Iter:26 train-loss:0.073109 valid-loss:0.110369  train-accuracy:1.000000 valid-accuracy:0.994363
# 	Iter:36 train-loss:0.026554 valid-loss:0.075320  train-accuracy:1.000000 valid-accuracy:0.994363
# 	Iter:46 train-loss:0.009724 valid-loss:0.069847  train-accuracy:1.000000 valid-accuracy:0.994363
# 	Iter:56 train-loss:0.003571 valid-loss:0.074999  train-accuracy:1.000000 valid-accuracy:0.994363
# 	Iter:66 train-loss:0.001313 valid-loss:0.084026  train-accuracy:1.000000 valid-accuracy:0.994363

# %%
# Model features
model.make_inspector().features()
# Out:
# ["10Percentile" (1; #0),
#  "90Percentile" (1; #1),
#  "Busyness" (1; #2),
#  "Coarseness" (1; #3),
#  "Complexity" (1; #4),
#  "Contrast" (1; #5),
#  "Energy" (1; #6),
#  "Entropy" (1; #7),
#  "InterquartileRange" (1; #8),
#  "Kurtosis" (1; #9),
#  "Maximum" (1; #10),
#  "Mean" (1; #11),
#  "MeanAbsoluteDeviation" (1; #12),
#  "Median" (1; #13),
#  "Minimum" (1; #14),
#  "Range" (1; #15),
#  "RobustMeanAbsoluteDeviation" (1; #16),
#  "RootMeanSquared" (1; #17),
#  "Skewness" (1; #18),
#  "Strength" (1; #19),
#  "TotalEnergy" (1; #20),
#  "Uniformity" (1; #21),
#  "Variance" (1; #22)]

# %%
# Feature importance
model.make_inspector().variable_importances()
# Out:
# {'INV_MEAN_MIN_DEPTH': [("Busyness" (1; #2), 1.0),
#   ("Contrast" (1; #5), 0.2599449143509223),
#   ("Complexity" (1; #4), 0.2590381986856626),
#   ("Coarseness" (1; #3), 0.2566771766992105),
#   ("Strength" (1; #19), 0.25575547201687815),
#   ("Uniformity" (1; #21), 0.24584924911915843),
#   ("Maximum" (1; #10), 0.2438645314346542),
#   ("Variance" (1; #22), 0.24308444816868197),
#   ("Energy" (1; #6), 0.24273493030370666),
#   ("InterquartileRange" (1; #8), 0.2424567551729064),
#   ("Mean" (1; #11), 0.24243913123840063),
#   ("10Percentile" (1; #0), 0.2423588192847209),
#   ("90Percentile" (1; #1), 0.2423588192847209),
#   ("RobustMeanAbsoluteDeviation" (1; #16), 0.24217714809907245),
#   ("Minimum" (1; #14), 0.24214560338980548),
#   ("MeanAbsoluteDeviation" (1; #12), 0.2420763373000163),
#   ("TotalEnergy" (1; #20), 0.24198903580541475),
#   ("Range" (1; #15), 0.24174563839433913),
#   ("Median" (1; #13), 0.241682173023821),
#   ("Kurtosis" (1; #9), 0.24156067483617097),
#   ("Skewness" (1; #18), 0.24130161270104594),
#   ("RootMeanSquared" (1; #17), 0.24104422351837215),
#   ("Entropy" (1; #7), 0.24096599663412574)],
#  'SUM_SCORE': [("Busyness" (1; #2), 1910.6769872784869),
#   ("Coarseness" (1; #3), 3.7715843130888445e-14),
#   ("Complexity" (1; #4), 3.410479950570158e-14),
#   ("Maximum" (1; #10), 3.0032400022785183e-14),
#   ("Energy" (1; #6), 2.6436318909832077e-14),
#   ("Range" (1; #15), 2.4313884055939102e-14),
#   ("Strength" (1; #19), 2.1952139583263827e-14),
#   ("90Percentile" (1; #1), 2.1323221168370983e-14),
#   ("RobustMeanAbsoluteDeviation" (1; #16), 1.4675326669879087e-14),
#   ("10Percentile" (1; #0), 1.001976299701978e-14),
#   ("Contrast" (1; #5), 8.593061320273748e-15),
#   ("Kurtosis" (1; #9), 5.7732682100920415e-15),
#   ("TotalEnergy" (1; #20), 4.556684896742511e-15),
#   ("Entropy" (1; #7), 2.3037128440779466e-15),
#   ("InterquartileRange" (1; #8), 2.263814190223469e-15),
#   ("Median" (1; #13), 1.7837294869652947e-15),
#   ("Variance" (1; #22), 1.0842021840278212e-15),
#   ("Uniformity" (1; #21), 9.835881978843336e-16),
#   ("Mean" (1; #11), 7.424616448415832e-16),
#   ("MeanAbsoluteDeviation" (1; #12), 5.34511676370409e-16),
#   ("RootMeanSquared" (1; #17), 4.445228825525707e-16),
#   ("Minimum" (1; #14), 1.7000289909247888e-16),
#   ("Skewness" (1; #18), 7.155734208999067e-18)],
#  'NUM_AS_ROOT': [("Busyness" (1; #2), 45.0)],
#  'NUM_NODES': [("Busyness" (1; #2), 117.0),
#   ("Contrast" (1; #5), 34.0),
#   ("Coarseness" (1; #3), 32.0),
#   ("Complexity" (1; #4), 31.0),
#   ("Strength" (1; #19), 29.0),
#   ("Uniformity" (1; #21), 8.0),
#   ("Variance" (1; #22), 7.0),
#   ("Maximum" (1; #10), 6.0),
#   ("Energy" (1; #6), 5.0),
#   ("InterquartileRange" (1; #8), 5.0),
#   ("MeanAbsoluteDeviation" (1; #12), 5.0),
#   ("Median" (1; #13), 5.0),
#   ("Range" (1; #15), 5.0),
#   ("RobustMeanAbsoluteDeviation" (1; #16), 5.0),
#   ("Mean" (1; #11), 4.0),
#   ("Minimum" (1; #14), 4.0),
#   ("10Percentile" (1; #0), 3.0),
#   ("Kurtosis" (1; #9), 3.0),
#   ("TotalEnergy" (1; #20), 3.0),
#   ("90Percentile" (1; #1), 2.0),
#   ("Entropy" (1; #7), 2.0),
#   ("RootMeanSquared" (1; #17), 2.0),
#   ("Skewness" (1; #18), 2.0)]}

# %%
# Model self evaluation
model.make_inspector().evaluation()
# Out:
# Evaluation(num_examples=None, accuracy=0.9943631291389465, loss=0.06974038481712341, rmse=None, ndcg=None, aucs=None, auuc=None, qini=None)

# %%
logs = model.make_inspector().training_logs()

plt.figure(figsize=(12, 4))
plt.subplot(1, 2, 1)
plt.plot([log.num_trees for log in logs], [log.evaluation.accuracy for log in logs])
plt.xlabel("Number of trees")
plt.ylabel("Accuracy (out-of-bag)")
plt.subplot(1, 2, 2)
plt.plot([log.num_trees for log in logs], [log.evaluation.loss for log in logs])
plt.xlabel("Number of trees")
plt.ylabel("Logloss (out-of-bag)")
plt.show()

# %% [markdown]
# Calculate the score of our hold-out validation dataset

# %%
predictions = model.predict(val_ds)
y_true      = validation_data["label"]

from sklearn.metrics import roc_auc_score
ROC_AUC = roc_auc_score(y_true, predictions)
print("The ROC AUC score is %.5f" % ROC_AUC )
# Out:
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 82ms/step
# The ROC AUC score is 1.00000

# %%
# Compute binary classification metrics with sklearn
import numpy as np
from sklearn.metrics import (
    accuracy_score,
    precision_score,
    recall_score,
    f1_score,
    roc_auc_score,
    average_precision_score,
    confusion_matrix,
    classification_report,
    matthews_corrcoef,
    log_loss,
    brier_score_loss,
)

# Get predictions (probabilities or class labels)
preds = model.predict(test_ds)
# If model outputs probabilities, convert to labels by threshold 0.5
if preds.ndim == 2:
    # For TFDF classification, preds may be class probabilities with shape (N, 2)
    if preds.shape[1] == 2:
        pos_probs = preds[:, 1]
    else:
        # If single-probability column (positive class)
        pos_probs = preds[:, -1]
    y_pred = (pos_probs >= 0.5).astype(int)
else:
    # Already class labels
    y_pred = preds.astype(int)
    pos_probs = None

# Ground truth labels (must be 0/1 integers)
y_true = test_data["label"].astype(int).to_numpy()

# Core metrics
metrics = {}
metrics["accuracy"] = accuracy_score(y_true, y_pred)
metrics["precision"] = precision_score(y_true, y_pred, zero_division=0)
metrics["recall"] = recall_score(y_true, y_pred, zero_division=0)
metrics["f1"] = f1_score(y_true, y_pred, zero_division=0)
metrics["mcc"] = matthews_corrcoef(y_true, y_pred)

# Probabilistic metrics (only if we have probabilities)
if pos_probs is not None:
    metrics["roc_auc"] = roc_auc_score(y_true, pos_probs)
    metrics["pr_auc"] = average_precision_score(y_true, pos_probs)
    metrics["log_loss"] = log_loss(y_true, pos_probs, labels=[0,1])
    metrics["brier_score"] = brier_score_loss(y_true, pos_probs)

# Confusion matrix and detailed report
cm = confusion_matrix(y_true, y_pred, labels=[0,1])
report = classification_report(y_true, y_pred, digits=4)

print("Sklearn binary metrics:")
for k, v in metrics.items():
    print(f"{k}: {v:.4f}")
print("\nConfusion matrix:\n", cm)
print("\nClassification report:\n", report)
# Out:
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 74ms/step
# Sklearn binary metrics:
# accuracy: 1.0000
# precision: 1.0000
# recall: 1.0000
# f1: 1.0000
# mcc: 1.0000
# roc_auc: 1.0000
# pr_auc: 1.0000
# log_loss: 0.0054
# brier_score: 0.0000
#
# Confusion matrix:
#  [[342   0]
#  [  0 100]]
#
# Classification report:
#                precision    recall  f1-score   support
#
#            0     1.0000    1.0000    1.0000       342
#            1     1.0000    1.0000    1.0000       100
#
#     accuracy                         1.0000       442
#    macro avg     1.0000    1.0000    1.0000       442
# weighted avg     1.0000    1.0000    1.0000       442
