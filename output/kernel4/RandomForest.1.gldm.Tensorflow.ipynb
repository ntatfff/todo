# %%
# Import packages and modules
import numpy  as np
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow_decision_forests as tfdf

from sklearn.model_selection import train_test_split
# Out:
# 2026-08-15 05:13:52.770405: I tensorflow/core/util/port.cc:113] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2026-08-15 05:13:53.152033: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2026-08-15 05:13:57.856103: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
# Check the version of TensorFlow Decision Forests
print("Found TensorFlow Decision Forests v" + tfdf.__version__)
# Out:
# Found TensorFlow Decision Forests v1.9.1

# %%
datasetPath = 'dataset/firstorder/kernel5/dataset.csv'

# %%
# Parameters
datasetPath = "dataset/gldm/kernel4/1.dataset.csv"

# %%
# train/validation/test = 70/10/20
dataset = pd.read_csv(datasetPath)

train_data, temp_data = train_test_split(dataset, test_size=0.3, random_state=42)
validation_data, test_data = train_test_split(temp_data, test_size=2/3, random_state=42)

# %%
from sklearn.utils.class_weight import compute_class_weight

# tinh class weight tren tap train
classes = np.array([0, 1])
weights = compute_class_weight(class_weight="balanced", classes=classes, y=train_data["label"])
class_weight = {0: weights[0], 1: weights[1]}

# gan sample_weight cho tung dong
train_data["sample_weight"] = train_data["label"].map(class_weight)
validation_data["sample_weight"] = validation_data["label"].map(class_weight)
test_data["sample_weight"] = test_data["label"].map(class_weight)

# Convert the dataset into a TensorFlow dataset.
train_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    train_data, label="label", weight="sample_weight"
)         
val_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    validation_data, label="label", weight="sample_weight"
)
test_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    test_data, label="label", weight="sample_weight"
)
# Out:
# 2026-08-15 05:14:11.485086: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:984] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2026-08-15 05:14:11.487243: W tensorflow/core/common_runtime/gpu/gpu_device.cc:2251] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...

# %%
import keras

# %%
# %%time

# Train a Random Forest model.
model = tfdf.keras.RandomForestModel()

# Add evaluation metrics
model.compile(
    metrics=["accuracy"]
)
model.fit(x=train_ds)

# # Train a Gradient Boosted Trees model.
# model = tfdf.keras.GradientBoostedTreesModel(num_trees=1500)
# model.fit(train_ds)
# Out:
# Use /tmp/tmpcim9jlgr as temporary training directory
# Reading training dataset...
# Training dataset read in 0:00:02.581234. Found 1554 examples.
# Training model...
# Model trained in 0:00:00.063663
# Compiling model...
# [INFO 26-08-15 05:14:14.2944 UTC kernel.cc:1233] Loading model from path /tmp/tmpcim9jlgr/model/ with prefix 219cc6ad1d504d3f
# [INFO 26-08-15 05:14:14.3022 UTC decision_forest.cc:734] Model loaded with 300 root(s), 6198 node(s), and 14 input feature(s).
# [INFO 26-08-15 05:14:14.3022 UTC abstract_model.cc:1362] Engine "RandomForestOptPred" built
# [INFO 26-08-15 05:14:14.3023 UTC kernel.cc:1061] Use fast generic engine
# Model compiled.
# CPU times: user 5.58 s, sys: 88.6 ms, total: 5.67 s
# Wall time: 5.79 s

# %%
# Evaluate the model
evaluate = model.evaluate(val_ds, return_dict=True)
print()

for name, value in evaluate.items():
    print(f"{name}: {value:.4f}")
# Out:
# WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 1/1 [==============================] - ETA: 0s - loss: 0.0000e+00 - accuracy: 0.9820
# 1/1 [==============================] - 3s 3s/step - loss: 0.0000e+00 - accuracy: 0.9820
# loss: 0.0000
# accuracy: 0.9820

# %%
# Model Summary
model.summary()
# Out:
# Model: "random_forest_model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
# =================================================================
# Total params: 1 (1.00 Byte)
# Trainable params: 0 (0.00 Byte)
# Non-trainable params: 1 (1.00 Byte)
# _________________________________________________________________
# Type: "RANDOM_FOREST"
# Task: CLASSIFICATION
# Label: "__LABEL"
#
# Input Features (14):
# 	DependenceEntropy
# 	DependenceNonUniformity
# 	DependenceNonUniformityNormalized
# 	DependenceVariance
# 	GrayLevelNonUniformity
# 	GrayLevelVariance
# 	HighGrayLevelEmphasis
# 	LargeDependenceEmphasis
# 	LargeDependenceHighGrayLevelEmphasis
# 	LargeDependenceLowGrayLevelEmphasis
# 	LowGrayLevelEmphasis
# 	SmallDependenceEmphasis
# 	SmallDependenceHighGrayLevelEmphasis
# 	SmallDependenceLowGrayLevelEmphasis
#
# Trained with weights
#
# Variable Importance: INV_MEAN_MIN_DEPTH:
#     1.                "HighGrayLevelEmphasis"  0.363073 ################
#     2. "SmallDependenceHighGrayLevelEmphasis"  0.313219 ##########
#     3.                 "LowGrayLevelEmphasis"  0.266160 #####
#     4.                    "DependenceEntropy"  0.248840 ###
#     5.               "GrayLevelNonUniformity"  0.248401 ###
#     6.  "LargeDependenceLowGrayLevelEmphasis"  0.246472 ###
#     7.  "SmallDependenceLowGrayLevelEmphasis"  0.235437 ##
#     8. "LargeDependenceHighGrayLevelEmphasis"  0.221680 #
#     9.                    "GrayLevelVariance"  0.219508
#    10.                   "DependenceVariance"  0.217134
#    11.              "LargeDependenceEmphasis"  0.214010
#    12.              "SmallDependenceEmphasis"  0.213800
#    13.              "DependenceNonUniformity"  0.213047
#    14.    "DependenceNonUniformityNormalized"  0.211257
#
# Variable Importance: NUM_AS_ROOT:
#     1.                "HighGrayLevelEmphasis" 108.000000 ################
#     2. "SmallDependenceHighGrayLevelEmphasis" 84.000000 ############
#     3.                 "LowGrayLevelEmphasis" 38.000000 #####
#     4.  "LargeDependenceLowGrayLevelEmphasis" 32.000000 ####
#     5.  "SmallDependenceLowGrayLevelEmphasis" 18.000000 ##
#     6.               "GrayLevelNonUniformity" 10.000000
#     7. "LargeDependenceHighGrayLevelEmphasis"  6.000000
#     8.                    "DependenceEntropy"  4.000000
#
# Variable Importance: NUM_NODES:
#     1.                "HighGrayLevelEmphasis" 505.000000 ################
#     2.                    "DependenceEntropy" 346.000000 ##########
#     3.                 "LowGrayLevelEmphasis" 326.000000 #########
#     4.               "GrayLevelNonUniformity" 304.000000 ########
#     5. "SmallDependenceHighGrayLevelEmphasis" 303.000000 ########
#     6.  "LargeDependenceLowGrayLevelEmphasis" 231.000000 #####
#     7.  "SmallDependenceLowGrayLevelEmphasis" 195.000000 ####
#     8. "LargeDependenceHighGrayLevelEmphasis" 151.000000 ###
#     9.                    "GrayLevelVariance" 140.000000 ##
#    10.                   "DependenceVariance" 125.000000 ##
#    11.              "SmallDependenceEmphasis" 102.000000 #
#    12.              "DependenceNonUniformity" 76.000000
#    13.              "LargeDependenceEmphasis" 76.000000
#    14.    "DependenceNonUniformityNormalized" 69.000000
#
# Variable Importance: SUM_SCORE:
#     1.                "HighGrayLevelEmphasis" 111555.743605 ################
#     2. "SmallDependenceHighGrayLevelEmphasis" 75551.561062 ##########
#     3.                 "LowGrayLevelEmphasis" 38128.733823 #####
#     4.  "LargeDependenceLowGrayLevelEmphasis" 25987.175020 ###
#     5.               "GrayLevelNonUniformity" 21220.737890 ##
#     6.                    "DependenceEntropy" 20274.911810 ##
#     7.  "SmallDependenceLowGrayLevelEmphasis" 10684.704538 #
#     8. "LargeDependenceHighGrayLevelEmphasis" 4151.757996
#     9.                    "GrayLevelVariance" 3400.846958
#    10.                   "DependenceVariance" 1817.708011
#    11.              "LargeDependenceEmphasis" 1795.700405
#    12.              "DependenceNonUniformity" 1673.869591
#    13.              "SmallDependenceEmphasis" 1596.115930
#    14.    "DependenceNonUniformityNormalized" 969.070742
#
#
#
# Winner takes all: true
# Out-of-bag evaluation: accuracy:0.962594 logloss:0.0839222
# Number of trees: 300
# Total number of nodes: 6198
#
# Number of nodes by tree:
# Count: 300 Average: 20.66 StdDev: 4.24316
# Min: 11 Max: 35 Ignored: 0
# ----------------------------------------------
# [ 11, 12)  2   0.67%   0.67%
# [ 12, 13)  0   0.00%   0.67%
# [ 13, 14) 11   3.67%   4.33% ##
# [ 14, 16) 31  10.33%  14.67% #####
# [ 16, 17)  0   0.00%  14.67%
# [ 17, 18) 39  13.00%  27.67% #######
# [ 18, 19)  0   0.00%  27.67%
# [ 19, 21) 59  19.67%  47.33% ##########
# [ 21, 22) 44  14.67%  62.00% #######
# [ 22, 23)  0   0.00%  62.00%
# [ 23, 24) 48  16.00%  78.00% ########
# [ 24, 26) 35  11.67%  89.67% ######
# [ 26, 27)  0   0.00%  89.67%
# [ 27, 28) 15   5.00%  94.67% ###
# [ 28, 29)  0   0.00%  94.67%
# [ 29, 31) 12   4.00%  98.67% ##
# [ 31, 32)  3   1.00%  99.67% #
# [ 32, 33)  0   0.00%  99.67%
# [ 33, 34)  0   0.00%  99.67%
# [ 34, 35]  1   0.33% 100.00%
#
# Depth by leafs:
# Count: 3249 Average: 3.89658 StdDev: 1.22043
# Min: 1 Max: 8 Ignored: 0
# ----------------------------------------------
# [ 1, 2)   12   0.37%   0.37%
# [ 2, 3)  379  11.67%  12.03% ####
# [ 3, 4)  889  27.36%  39.40% #########
# [ 4, 5) 1035  31.86%  71.25% ##########
# [ 5, 6)  607  18.68%  89.94% ######
# [ 6, 7)  249   7.66%  97.60% ##
# [ 7, 8)   70   2.15%  99.75% #
# [ 8, 8]    8   0.25% 100.00%
#
# Number of training obs by leaf:
# Count: 3249 Average: 143.49 StdDev: 363.363
# Min: 5 Max: 1432 Ignored: 0
# ----------------------------------------------
# [    5,   76) 2623  80.73%  80.73% ##########
# [   76,  147)  240   7.39%  88.12% #
# [  147,  219)   43   1.32%  89.44%
# [  219,  290)   13   0.40%  89.84%
# [  290,  362)   21   0.65%  90.49%
# [  362,  433)    7   0.22%  90.70%
# [  433,  504)    2   0.06%  90.77%
# [  504,  576)    0   0.00%  90.77%
# [  576,  647)    0   0.00%  90.77%
# [  647,  719)    0   0.00%  90.77%
# [  719,  790)    0   0.00%  90.77%
# [  790,  861)    2   0.06%  90.83%
# [  861,  933)    5   0.15%  90.98%
# [  933, 1004)    8   0.25%  91.23%
# [ 1004, 1076)   16   0.49%  91.72%
# [ 1076, 1147)   11   0.34%  92.06%
# [ 1147, 1218)   54   1.66%  93.72%
# [ 1218, 1290)   35   1.08%  94.80%
# [ 1290, 1361)   88   2.71%  97.51%
# [ 1361, 1432]   81   2.49% 100.00%
#
# Attribute in nodes:
# 	505 : HighGrayLevelEmphasis [NUMERICAL]
# 	346 : DependenceEntropy [NUMERICAL]
# 	326 : LowGrayLevelEmphasis [NUMERICAL]
# 	304 : GrayLevelNonUniformity [NUMERICAL]
# 	303 : SmallDependenceHighGrayLevelEmphasis [NUMERICAL]
# 	231 : LargeDependenceLowGrayLevelEmphasis [NUMERICAL]
# 	195 : SmallDependenceLowGrayLevelEmphasis [NUMERICAL]
# 	151 : LargeDependenceHighGrayLevelEmphasis [NUMERICAL]
# 	140 : GrayLevelVariance [NUMERICAL]
# 	125 : DependenceVariance [NUMERICAL]
# 	102 : SmallDependenceEmphasis [NUMERICAL]
# 	76 : LargeDependenceEmphasis [NUMERICAL]
# 	76 : DependenceNonUniformity [NUMERICAL]
# 	69 : DependenceNonUniformityNormalized [NUMERICAL]
#
# Attribute in nodes with depth <= 0:
# 	108 : HighGrayLevelEmphasis [NUMERICAL]
# 	84 : SmallDependenceHighGrayLevelEmphasis [NUMERICAL]
# 	38 : LowGrayLevelEmphasis [NUMERICAL]
# 	32 : LargeDependenceLowGrayLevelEmphasis [NUMERICAL]
# 	18 : SmallDependenceLowGrayLevelEmphasis [NUMERICAL]
# 	10 : GrayLevelNonUniformity [NUMERICAL]
# 	6 : LargeDependenceHighGrayLevelEmphasis [NUMERICAL]
# 	4 : DependenceEntropy [NUMERICAL]
#
# Attribute in nodes with depth <= 1:
# 	257 : HighGrayLevelEmphasis [NUMERICAL]
# 	180 : SmallDependenceHighGrayLevelEmphasis [NUMERICAL]
# 	103 : LowGrayLevelEmphasis [NUMERICAL]
# 	101 : DependenceEntropy [NUMERICAL]
# 	82 : GrayLevelNonUniformity [NUMERICAL]
# 	53 : LargeDependenceLowGrayLevelEmphasis [NUMERICAL]
# 	36 : SmallDependenceLowGrayLevelEmphasis [NUMERICAL]
# 	22 : LargeDependenceHighGrayLevelEmphasis [NUMERICAL]
# 	15 : LargeDependenceEmphasis [NUMERICAL]
# 	10 : DependenceNonUniformity [NUMERICAL]
# 	8 : GrayLevelVariance [NUMERICAL]
# 	8 : DependenceVariance [NUMERICAL]
# 	7 : DependenceNonUniformityNormalized [NUMERICAL]
# 	6 : SmallDependenceEmphasis [NUMERICAL]
#
# Attribute in nodes with depth <= 2:
# 	389 : HighGrayLevelEmphasis [NUMERICAL]
# 	233 : SmallDependenceHighGrayLevelEmphasis [NUMERICAL]
# 	212 : DependenceEntropy [NUMERICAL]
# 	195 : LowGrayLevelEmphasis [NUMERICAL]
# 	173 : GrayLevelNonUniformity [NUMERICAL]
# 	115 : LargeDependenceLowGrayLevelEmphasis [NUMERICAL]
# 	93 : SmallDependenceLowGrayLevelEmphasis [NUMERICAL]
# 	71 : LargeDependenceHighGrayLevelEmphasis [NUMERICAL]
# 	56 : GrayLevelVariance [NUMERICAL]
# 	38 : DependenceVariance [NUMERICAL]
# 	34 : SmallDependenceEmphasis [NUMERICAL]
# 	31 : LargeDependenceEmphasis [NUMERICAL]
# 	24 : DependenceNonUniformity [NUMERICAL]
# 	21 : DependenceNonUniformityNormalized [NUMERICAL]
#
# Attribute in nodes with depth <= 3:
# 	460 : HighGrayLevelEmphasis [NUMERICAL]
# 	295 : DependenceEntropy [NUMERICAL]
# 	277 : LowGrayLevelEmphasis [NUMERICAL]
# 	268 : SmallDependenceHighGrayLevelEmphasis [NUMERICAL]
# 	246 : GrayLevelNonUniformity [NUMERICAL]
# 	182 : LargeDependenceLowGrayLevelEmphasis [NUMERICAL]
# 	150 : SmallDependenceLowGrayLevelEmphasis [NUMERICAL]
# 	114 : LargeDependenceHighGrayLevelEmphasis [NUMERICAL]
# 	103 : GrayLevelVariance [NUMERICAL]
# 	79 : DependenceVariance [NUMERICAL]
# 	65 : SmallDependenceEmphasis [NUMERICAL]
# 	59 : LargeDependenceEmphasis [NUMERICAL]
# 	47 : DependenceNonUniformity [NUMERICAL]
# 	45 : DependenceNonUniformityNormalized [NUMERICAL]
#
# Attribute in nodes with depth <= 5:
# 	503 : HighGrayLevelEmphasis [NUMERICAL]
# 	341 : DependenceEntropy [NUMERICAL]
# 	322 : LowGrayLevelEmphasis [NUMERICAL]
# 	301 : SmallDependenceHighGrayLevelEmphasis [NUMERICAL]
# 	299 : GrayLevelNonUniformity [NUMERICAL]
# 	227 : LargeDependenceLowGrayLevelEmphasis [NUMERICAL]
# 	194 : SmallDependenceLowGrayLevelEmphasis [NUMERICAL]
# 	146 : LargeDependenceHighGrayLevelEmphasis [NUMERICAL]
# 	140 : GrayLevelVariance [NUMERICAL]
# 	121 : DependenceVariance [NUMERICAL]
# 	100 : SmallDependenceEmphasis [NUMERICAL]
# 	76 : LargeDependenceEmphasis [NUMERICAL]
# 	73 : DependenceNonUniformity [NUMERICAL]
# 	65 : DependenceNonUniformityNormalized [NUMERICAL]
#
# Condition type in nodes:
# 	2949 : HigherCondition
# Condition type in nodes with depth <= 0:
# 	300 : HigherCondition
# Condition type in nodes with depth <= 1:
# 	888 : HigherCondition
# Condition type in nodes with depth <= 2:
# 	1685 : HigherCondition
# Condition type in nodes with depth <= 3:
# 	2390 : HigherCondition
# Condition type in nodes with depth <= 5:
# 	2908 : HigherCondition
# Node format: NOT_SET
#
# Training OOB:
# 	trees: 1, Out-of-bag evaluation: accuracy:0.933177 logloss:2.40856
# 	trees: 11, Out-of-bag evaluation: accuracy:0.936884 logloss:1.11107
# 	trees: 21, Out-of-bag evaluation: accuracy:0.957027 logloss:0.595291
# 	trees: 32, Out-of-bag evaluation: accuracy:0.957299 logloss:0.253188
# 	trees: 42, Out-of-bag evaluation: accuracy:0.957643 logloss:0.252375
# 	trees: 53, Out-of-bag evaluation: accuracy:0.967544 logloss:0.083425
# 	trees: 63, Out-of-bag evaluation: accuracy:0.96225 logloss:0.0871871
# 	trees: 73, Out-of-bag evaluation: accuracy:0.96225 logloss:0.0873779
# 	trees: 83, Out-of-bag evaluation: accuracy:0.962594 logloss:0.0863146
# 	trees: 95, Out-of-bag evaluation: accuracy:0.96225 logloss:0.0859395
# 	trees: 105, Out-of-bag evaluation: accuracy:0.96225 logloss:0.0869995
# 	trees: 115, Out-of-bag evaluation: accuracy:0.961905 logloss:0.0901786
# 	trees: 125, Out-of-bag evaluation: accuracy:0.961905 logloss:0.0926614
# 	trees: 137, Out-of-bag evaluation: accuracy:0.96225 logloss:0.0925393
# 	trees: 147, Out-of-bag evaluation: accuracy:0.96225 logloss:0.0923953
# 	trees: 160, Out-of-bag evaluation: accuracy:0.962594 logloss:0.0934821
# 	trees: 170, Out-of-bag evaluation: accuracy:0.962594 logloss:0.0938744
# 	trees: 180, Out-of-bag evaluation: accuracy:0.962594 logloss:0.0940831
# 	trees: 191, Out-of-bag evaluation: accuracy:0.962594 logloss:0.0929555
# 	trees: 201, Out-of-bag evaluation: accuracy:0.962938 logloss:0.0927303
# 	trees: 211, Out-of-bag evaluation: accuracy:0.962938 logloss:0.092577
# 	trees: 222, Out-of-bag evaluation: accuracy:0.962938 logloss:0.0919459
# 	trees: 232, Out-of-bag evaluation: accuracy:0.962594 logloss:0.0911743
# 	trees: 242, Out-of-bag evaluation: accuracy:0.962594 logloss:0.0892537
# 	trees: 252, Out-of-bag evaluation: accuracy:0.96225 logloss:0.0878517
# 	trees: 262, Out-of-bag evaluation: accuracy:0.962594 logloss:0.086455
# 	trees: 272, Out-of-bag evaluation: accuracy:0.962594 logloss:0.0858043
# 	trees: 282, Out-of-bag evaluation: accuracy:0.962594 logloss:0.0845301
# 	trees: 293, Out-of-bag evaluation: accuracy:0.96225 logloss:0.0838743
# 	trees: 300, Out-of-bag evaluation: accuracy:0.962594 logloss:0.0839222

# %%
# Model features
model.make_inspector().features()
# Out:
# ["DependenceEntropy" (1; #0),
#  "DependenceNonUniformity" (1; #1),
#  "DependenceNonUniformityNormalized" (1; #2),
#  "DependenceVariance" (1; #3),
#  "GrayLevelNonUniformity" (1; #4),
#  "GrayLevelVariance" (1; #5),
#  "HighGrayLevelEmphasis" (1; #6),
#  "LargeDependenceEmphasis" (1; #7),
#  "LargeDependenceHighGrayLevelEmphasis" (1; #8),
#  "LargeDependenceLowGrayLevelEmphasis" (1; #9),
#  "LowGrayLevelEmphasis" (1; #10),
#  "SmallDependenceEmphasis" (1; #11),
#  "SmallDependenceHighGrayLevelEmphasis" (1; #12),
#  "SmallDependenceLowGrayLevelEmphasis" (1; #13)]

# %%
# Feature importance
model.make_inspector().variable_importances()
# Out:
# {'INV_MEAN_MIN_DEPTH': [("HighGrayLevelEmphasis" (1; #6), 0.36307347499959386),
#   ("SmallDependenceHighGrayLevelEmphasis" (1; #12), 0.3132185385322891),
#   ("LowGrayLevelEmphasis" (1; #10), 0.2661601335450862),
#   ("DependenceEntropy" (1; #0), 0.24884023052312398),
#   ("GrayLevelNonUniformity" (1; #4), 0.24840051299296756),
#   ("LargeDependenceLowGrayLevelEmphasis" (1; #9), 0.24647180854323075),
#   ("SmallDependenceLowGrayLevelEmphasis" (1; #13), 0.2354372557753343),
#   ("LargeDependenceHighGrayLevelEmphasis" (1; #8), 0.2216800680789193),
#   ("GrayLevelVariance" (1; #5), 0.21950760655846296),
#   ("DependenceVariance" (1; #3), 0.2171338538963564),
#   ("LargeDependenceEmphasis" (1; #7), 0.21401010941607349),
#   ("SmallDependenceEmphasis" (1; #11), 0.21379950839363315),
#   ("DependenceNonUniformity" (1; #1), 0.2130471429737753),
#   ("DependenceNonUniformityNormalized" (1; #2), 0.21125660438863686)],
#  'NUM_AS_ROOT': [("HighGrayLevelEmphasis" (1; #6), 108.0),
#   ("SmallDependenceHighGrayLevelEmphasis" (1; #12), 84.0),
#   ("LowGrayLevelEmphasis" (1; #10), 38.0),
#   ("LargeDependenceLowGrayLevelEmphasis" (1; #9), 32.0),
#   ("SmallDependenceLowGrayLevelEmphasis" (1; #13), 18.0),
#   ("GrayLevelNonUniformity" (1; #4), 10.0),
#   ("LargeDependenceHighGrayLevelEmphasis" (1; #8), 6.0),
#   ("DependenceEntropy" (1; #0), 4.0)],
#  'SUM_SCORE': [("HighGrayLevelEmphasis" (1; #6), 111555.74360458809),
#   ("SmallDependenceHighGrayLevelEmphasis" (1; #12), 75551.5610622133),
#   ("LowGrayLevelEmphasis" (1; #10), 38128.733823022056),
#   ("LargeDependenceLowGrayLevelEmphasis" (1; #9), 25987.17501971857),
#   ("GrayLevelNonUniformity" (1; #4), 21220.73788994263),
#   ("DependenceEntropy" (1; #0), 20274.911810161528),
#   ("SmallDependenceLowGrayLevelEmphasis" (1; #13), 10684.704538351532),
#   ("LargeDependenceHighGrayLevelEmphasis" (1; #8), 4151.757996265157),
#   ("GrayLevelVariance" (1; #5), 3400.846957841574),
#   ("DependenceVariance" (1; #3), 1817.708010956831),
#   ("LargeDependenceEmphasis" (1; #7), 1795.700404722362),
#   ("DependenceNonUniformity" (1; #1), 1673.8695914010482),
#   ("SmallDependenceEmphasis" (1; #11), 1596.1159302635033),
#   ("DependenceNonUniformityNormalized" (1; #2), 969.0707418627311)],
#  'NUM_NODES': [("HighGrayLevelEmphasis" (1; #6), 505.0),
#   ("DependenceEntropy" (1; #0), 346.0),
#   ("LowGrayLevelEmphasis" (1; #10), 326.0),
#   ("GrayLevelNonUniformity" (1; #4), 304.0),
#   ("SmallDependenceHighGrayLevelEmphasis" (1; #12), 303.0),
#   ("LargeDependenceLowGrayLevelEmphasis" (1; #9), 231.0),
#   ("SmallDependenceLowGrayLevelEmphasis" (1; #13), 195.0),
#   ("LargeDependenceHighGrayLevelEmphasis" (1; #8), 151.0),
#   ("GrayLevelVariance" (1; #5), 140.0),
#   ("DependenceVariance" (1; #3), 125.0),
#   ("SmallDependenceEmphasis" (1; #11), 102.0),
#   ("DependenceNonUniformity" (1; #1), 76.0),
#   ("LargeDependenceEmphasis" (1; #7), 76.0),
#   ("DependenceNonUniformityNormalized" (1; #2), 69.0)]}

# %%
# Model self evaluation
model.make_inspector().evaluation()
# Out:
# Evaluation(num_examples=1554, accuracy=0.9625936102188284, loss=0.08392217194725636, rmse=None, ndcg=None, aucs=None, auuc=None, qini=None)

# %%
logs = model.make_inspector().training_logs()

plt.figure(figsize=(12, 4))
plt.subplot(1, 2, 1)
plt.plot([log.num_trees for log in logs], [log.evaluation.accuracy for log in logs])
plt.xlabel("Number of trees")
plt.ylabel("Accuracy (out-of-bag)")
plt.subplot(1, 2, 2)
plt.plot([log.num_trees for log in logs], [log.evaluation.loss for log in logs])
plt.xlabel("Number of trees")
plt.ylabel("Logloss (out-of-bag)")
plt.show()

# %% [markdown]
# Calculate the score of our hold-out validation dataset

# %%
predictions = model.predict(val_ds)
y_true      = validation_data["label"]

from sklearn.metrics import roc_auc_score
ROC_AUC = roc_auc_score(y_true, predictions)
print("The ROC AUC score is %.5f" % ROC_AUC )
# Out:
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 62ms/step
# The ROC AUC score is 0.98849

# %%
# Compute binary classification metrics with sklearn
import numpy as np
from sklearn.metrics import (
    accuracy_score,
    precision_score,
    recall_score,
    f1_score,
    roc_auc_score,
    average_precision_score,
    confusion_matrix,
    classification_report,
    matthews_corrcoef,
    log_loss,
    brier_score_loss,
)

# Get predictions (probabilities or class labels)
preds = model.predict(test_ds)
# If model outputs probabilities, convert to labels by threshold 0.5
if preds.ndim == 2:
    # For TFDF classification, preds may be class probabilities with shape (N, 2)
    if preds.shape[1] == 2:
        pos_probs = preds[:, 1]
    else:
        # If single-probability column (positive class)
        pos_probs = preds[:, -1]
    y_pred = (pos_probs >= 0.5).astype(int)
else:
    # Already class labels
    y_pred = preds.astype(int)
    pos_probs = None

# Ground truth labels (must be 0/1 integers)
y_true = test_data["label"].astype(int).to_numpy()

# Core metrics
metrics = {}
metrics["accuracy"] = accuracy_score(y_true, y_pred)
metrics["precision"] = precision_score(y_true, y_pred, zero_division=0)
metrics["recall"] = recall_score(y_true, y_pred, zero_division=0)
metrics["f1"] = f1_score(y_true, y_pred, zero_division=0)
metrics["mcc"] = matthews_corrcoef(y_true, y_pred)

# Probabilistic metrics (only if we have probabilities)
if pos_probs is not None:
    metrics["roc_auc"] = roc_auc_score(y_true, pos_probs)
    metrics["pr_auc"] = average_precision_score(y_true, pos_probs)
    metrics["log_loss"] = log_loss(y_true, pos_probs, labels=[0,1])
    metrics["brier_score"] = brier_score_loss(y_true, pos_probs)

# Confusion matrix and detailed report
cm = confusion_matrix(y_true, y_pred, labels=[0,1])
report = classification_report(y_true, y_pred, digits=4)

print("Sklearn binary metrics:")
for k, v in metrics.items():
    print(f"{k}: {v:.4f}")
print("\nConfusion matrix:\n", cm)
print("\nClassification report:\n", report)
# Out:
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 65ms/step
# Sklearn binary metrics:
# accuracy: 0.9910
# precision: 0.8929
# recall: 0.9615
# f1: 0.9259
# mcc: 0.9219
# roc_auc: 0.9989
# pr_auc: 0.9855
# log_loss: 0.0250
# brier_score: 0.0071
#
# Confusion matrix:
#  [[415   3]
#  [  1  25]]
#
# Classification report:
#                precision    recall  f1-score   support
#
#            0     0.9976    0.9928    0.9952       418
#            1     0.8929    0.9615    0.9259        26
#
#     accuracy                         0.9910       444
#    macro avg     0.9452    0.9772    0.9606       444
# weighted avg     0.9915    0.9910    0.9911       444
