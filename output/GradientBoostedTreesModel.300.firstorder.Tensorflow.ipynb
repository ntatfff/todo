# %%
# Import packages and modules
import numpy  as np
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow_decision_forests as tfdf

from sklearn.model_selection import train_test_split
# Out:
# 2026-07-04 07:36:56.507040: I tensorflow/core/util/port.cc:113] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2026-07-04 07:36:56.549599: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2026-07-04 07:37:00.937107: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
# Check the version of TensorFlow Decision Forests
print("Found TensorFlow Decision Forests v" + tfdf.__version__)
# Out:
# Found TensorFlow Decision Forests v1.9.1

# %%
datasetPath = 'dataset/firstorder/kernel5-radius5/dataset.csv'

# %%
# Parameters
datasetPath = "dataset/firstorder/kernel5-radius5/300.dataset.csv"

# %%
# train/validation/test = 70/10/20
dataset = pd.read_csv(datasetPath)

train_data, temp_data = train_test_split(dataset, test_size=0.3, random_state=42)
validation_data, test_data = train_test_split(temp_data, test_size=2/3, random_state=42)

# %%
from sklearn.utils.class_weight import compute_class_weight

# tinh class weight tren tap train
classes = np.array([0, 1])
weights = compute_class_weight(class_weight="balanced", classes=classes, y=train_data["label"])
class_weight = {0: weights[0], 1: weights[1]}

# gan sample_weight cho tung dong
train_data["sample_weight"] = train_data["label"].map(class_weight)
validation_data["sample_weight"] = validation_data["label"].map(class_weight)
test_data["sample_weight"] = test_data["label"].map(class_weight)

# Convert the dataset into a TensorFlow dataset.
train_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    train_data, label="label", weight="sample_weight"
)         
val_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    validation_data, label="label", weight="sample_weight"
)
test_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    test_data, label="label", weight="sample_weight"
)
# Out:
# 2026-07-04 07:37:14.682592: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:984] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2026-07-04 07:37:14.683929: W tensorflow/core/common_runtime/gpu/gpu_device.cc:2251] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...

# %%
import keras

# %%
# %%time

# Train a Gradient Boosted Trees model.
model = tfdf.keras.GradientBoostedTreesModel()

# Add evaluation metrics
model.compile(
    metrics=["accuracy"]
)
model.fit(x=train_ds)

# # Train a Gradient Boosted Trees model.
# model = tfdf.keras.GradientBoostedTreesModel(num_trees=1500)
# model.fit(train_ds)
# Out:
# Use /tmp/tmpc9mpgiu4 as temporary training directory
# Reading training dataset...
# [WARNING 26-07-04 07:37:14.8582 UTC gradient_boosted_trees.cc:1840] "goss_alpha" set but "sampling_method" not equal to "GOSS".
# [WARNING 26-07-04 07:37:14.8582 UTC gradient_boosted_trees.cc:1851] "goss_beta" set but "sampling_method" not equal to "GOSS".
# [WARNING 26-07-04 07:37:14.8582 UTC gradient_boosted_trees.cc:1865] "selective_gradient_boosting_ratio" set but "sampling_method" not equal to "SELGB".
# Training dataset read in 0:00:03.583567. Found 235478 examples.
# Training model...
# Model trained in 0:00:44.989248
# Compiling model...
# [INFO 26-07-04 07:38:03.4421 UTC kernel.cc:1233] Loading model from path /tmp/tmpc9mpgiu4/model/ with prefix 3114cc8c2c8e4966
# [INFO 26-07-04 07:38:03.4529 UTC quick_scorer_extended.cc:911] The binary was compiled without AVX2 support, but your CPU supports it. Enable it for faster model inference.
# [INFO 26-07-04 07:38:03.4536 UTC abstract_model.cc:1362] Engine "GradientBoostedTreesQuickScorerExtended" built
# [INFO 26-07-04 07:38:03.4537 UTC kernel.cc:1061] Use fast generic engine
# Model compiled.
# CPU times: user 5min 50s, sys: 3.54 s, total: 5min 54s
# Wall time: 51.6 s

# %%
# Evaluate the model
evaluate = model.evaluate(val_ds, return_dict=True)
print()

for name, value in evaluate.items():
    print(f"{name}: {value:.4f}")
# Out:
# WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
#  1/34 [..............................] - ETA: 1:38 - loss: 0.0000e+00 - accuracy: 0.8860
# 12/34 [=========>....................] - ETA: 0s - loss: 0.0000e+00 - accuracy: 0.8863
# 24/34 [====================>.........] - ETA: 0s - loss: 0.0000e+00 - accuracy: 0.8901
# 34/34 [==============================] - 3s 5ms/step - loss: 0.0000e+00 - accuracy: 0.8898
# loss: 0.0000
# accuracy: 0.8898

# %%
# Model Summary
model.summary()
# Out:
# Model: "gradient_boosted_trees_model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
# =================================================================
# Total params: 1 (1.00 Byte)
# Trainable params: 0 (0.00 Byte)
# Non-trainable params: 1 (1.00 Byte)
# _________________________________________________________________
# Type: "GRADIENT_BOOSTED_TREES"
# Task: CLASSIFICATION
# Label: "__LABEL"
#
# Input Features (18):
# 	10Percentile
# 	90Percentile
# 	Energy
# 	Entropy
# 	InterquartileRange
# 	Kurtosis
# 	Maximum
# 	Mean
# 	MeanAbsoluteDeviation
# 	Median
# 	Minimum
# 	Range
# 	RobustMeanAbsoluteDeviation
# 	RootMeanSquared
# 	Skewness
# 	TotalEnergy
# 	Uniformity
# 	Variance
#
# Trained with weights
#
# Variable Importance: INV_MEAN_MIN_DEPTH:
#     1.                "90Percentile"  0.214233 ################
#     2.                     "Minimum"  0.211285 ##############
#     3.                    "Kurtosis"  0.209941 ##############
#     4.                    "Skewness"  0.206040 ############
#     5.                    "Variance"  0.202509 ###########
#     6.                     "Maximum"  0.201841 ###########
#     7.                "10Percentile"  0.198628 #########
#     8.                      "Median"  0.197292 #########
#     9.                       "Range"  0.195545 ########
#    10. "RobustMeanAbsoluteDeviation"  0.189424 ######
#    11.                        "Mean"  0.188410 #####
#    12.                  "Uniformity"  0.187835 #####
#    13.          "InterquartileRange"  0.185388 ####
#    14.       "MeanAbsoluteDeviation"  0.184292 ###
#    15.                     "Entropy"  0.180617 ##
#    16.             "RootMeanSquared"  0.177224 #
#    17.                 "TotalEnergy"  0.175516
#    18.                      "Energy"  0.174473
#
# Variable Importance: NUM_AS_ROOT:
#     1.                "90Percentile" 29.000000 ################
#     2.                     "Minimum" 26.000000 ##############
#     3.                    "Variance" 24.000000 #############
#     4.                    "Kurtosis" 20.000000 ##########
#     5.                      "Median" 14.000000 #######
#     6.                    "Skewness" 14.000000 #######
#     7.                "10Percentile" 13.000000 ######
#     8.                        "Mean" 13.000000 ######
#     9. "RobustMeanAbsoluteDeviation" 11.000000 #####
#    10.          "InterquartileRange"  9.000000 ####
#    11.       "MeanAbsoluteDeviation"  8.000000 ####
#    12.                       "Range"  7.000000 ###
#    13.                  "Uniformity"  6.000000 ##
#    14.                     "Maximum"  3.000000 #
#    15.             "RootMeanSquared"  3.000000 #
#    16.                 "TotalEnergy"  2.000000
#    17.                      "Energy"  1.000000
#    18.                     "Entropy"  1.000000
#
# Variable Importance: NUM_NODES:
#     1.                    "Skewness" 552.000000 ################
#     2.                    "Kurtosis" 490.000000 #############
#     3.                "90Percentile" 483.000000 #############
#     4.                     "Maximum" 444.000000 ############
#     5.                      "Median" 423.000000 ###########
#     6.                     "Minimum" 405.000000 ##########
#     7.                "10Percentile" 393.000000 ##########
#     8.                    "Variance" 330.000000 ########
#     9.                       "Range" 324.000000 ########
#    10.                  "Uniformity" 295.000000 #######
#    11. "RobustMeanAbsoluteDeviation" 275.000000 ######
#    12.          "InterquartileRange" 230.000000 ####
#    13.                        "Mean" 228.000000 ####
#    14.                     "Entropy" 225.000000 ####
#    15.       "MeanAbsoluteDeviation" 203.000000 ###
#    16.             "RootMeanSquared" 122.000000 #
#    17.                 "TotalEnergy" 96.000000
#    18.                      "Energy" 87.000000
#
# Variable Importance: SUM_SCORE:
#     1.                "90Percentile" 72180.167200 ################
#     2.                        "Mean" 38771.954029 ########
#     3.                     "Minimum" 11126.528409 ##
#     4.                "10Percentile" 10521.533680 ##
#     5.                    "Kurtosis" 9138.869585 #
#     6.                 "TotalEnergy" 8745.415427 #
#     7.                     "Maximum" 6859.403213 #
#     8.             "RootMeanSquared" 5919.633177 #
#     9.                      "Median" 4495.646465
#    10.                      "Energy" 4489.926164
#    11.                    "Skewness" 4289.631048
#    12.                  "Uniformity" 3130.479767
#    13.          "InterquartileRange" 3125.187976
#    14. "RobustMeanAbsoluteDeviation" 2911.578583
#    15.                       "Range" 2840.634292
#    16.                    "Variance" 2127.465048
#    17.       "MeanAbsoluteDeviation" 1612.088044
#    18.                     "Entropy" 1090.822941
#
#
#
# Loss: BINOMIAL_LOG_LIKELIHOOD
# Validation loss value: 0.620144
# Number of trees per iteration: 1
# Node format: NOT_SET
# Number of trees: 204
# Total number of nodes: 11414
#
# Number of nodes by tree:
# Count: 204 Average: 55.951 StdDev: 8.4446
# Min: 17 Max: 63 Ignored: 0
# ----------------------------------------------
# [ 17, 19)  3   1.47%   1.47%
# [ 19, 21)  0   0.00%   1.47%
# [ 21, 24)  0   0.00%   1.47%
# [ 24, 26)  1   0.49%   1.96%
# [ 26, 28)  0   0.00%   1.96%
# [ 28, 31)  0   0.00%   1.96%
# [ 31, 33)  0   0.00%   1.96%
# [ 33, 35)  0   0.00%   1.96%
# [ 35, 38)  3   1.47%   3.43%
# [ 38, 40)  2   0.98%   4.41%
# [ 40, 42)  1   0.49%   4.90%
# [ 42, 45)  4   1.96%   6.86%
# [ 45, 47)  4   1.96%   8.82%
# [ 47, 49) 11   5.39%  14.22% #
# [ 49, 52) 23  11.27%  25.49% ##
# [ 52, 54) 14   6.86%  32.35% ##
# [ 54, 56) 20   9.80%  42.16% ##
# [ 56, 59) 11   5.39%  47.55% #
# [ 59, 61) 14   6.86%  54.41% ##
# [ 61, 63] 93  45.59% 100.00% ##########
#
# Depth by leafs:
# Count: 5809 Average: 4.91031 StdDev: 0.374858
# Min: 2 Max: 5 Ignored: 0
# ----------------------------------------------
# [ 2, 3)   27   0.46%   0.46%
# [ 3, 4)   90   1.55%   2.01%
# [ 4, 5)  260   4.48%   6.49%
# [ 5, 5] 5432  93.51% 100.00% ##########
#
# Number of training obs by leaf:
# Count: 5809 Average: 7438.92 StdDev: 24956
# Min: 5 Max: 211718 Ignored: 0
# ----------------------------------------------
# [      5,  10590) 5054  87.00%  87.00% ##########
# [  10590,  21176)  315   5.42%  92.43% #
# [  21176,  31762)  132   2.27%  94.70%
# [  31762,  42347)   54   0.93%  95.63%
# [  42347,  52933)   42   0.72%  96.35%
# [  52933,  63519)   33   0.57%  96.92%
# [  63519,  74104)   23   0.40%  97.31%
# [  74104,  84690)   17   0.29%  97.61%
# [  84690,  95276)   11   0.19%  97.80%
# [  95276, 105862)   12   0.21%  98.00%
# [ 105862, 116447)   16   0.28%  98.28%
# [ 116447, 127033)   19   0.33%  98.61%
# [ 127033, 137619)    7   0.12%  98.73%
# [ 137619, 148204)    7   0.12%  98.85%
# [ 148204, 158790)    6   0.10%  98.95%
# [ 158790, 169376)   13   0.22%  99.17%
# [ 169376, 179961)    9   0.15%  99.33%
# [ 179961, 190547)   11   0.19%  99.52%
# [ 190547, 201133)    8   0.14%  99.66%
# [ 201133, 211718]   20   0.34% 100.00%
#
# Attribute in nodes:
# 	552 : Skewness [NUMERICAL]
# 	490 : Kurtosis [NUMERICAL]
# 	483 : 90Percentile [NUMERICAL]
# 	444 : Maximum [NUMERICAL]
# 	423 : Median [NUMERICAL]
# 	405 : Minimum [NUMERICAL]
# 	393 : 10Percentile [NUMERICAL]
# 	330 : Variance [NUMERICAL]
# 	324 : Range [NUMERICAL]
# 	295 : Uniformity [NUMERICAL]
# 	275 : RobustMeanAbsoluteDeviation [NUMERICAL]
# 	230 : InterquartileRange [NUMERICAL]
# 	228 : Mean [NUMERICAL]
# 	225 : Entropy [NUMERICAL]
# 	203 : MeanAbsoluteDeviation [NUMERICAL]
# 	122 : RootMeanSquared [NUMERICAL]
# 	96 : TotalEnergy [NUMERICAL]
# 	87 : Energy [NUMERICAL]
#
# Attribute in nodes with depth <= 0:
# 	29 : 90Percentile [NUMERICAL]
# 	26 : Minimum [NUMERICAL]
# 	24 : Variance [NUMERICAL]
# 	20 : Kurtosis [NUMERICAL]
# 	14 : Skewness [NUMERICAL]
# 	14 : Median [NUMERICAL]
# 	13 : Mean [NUMERICAL]
# 	13 : 10Percentile [NUMERICAL]
# 	11 : RobustMeanAbsoluteDeviation [NUMERICAL]
# 	9 : InterquartileRange [NUMERICAL]
# 	8 : MeanAbsoluteDeviation [NUMERICAL]
# 	7 : Range [NUMERICAL]
# 	6 : Uniformity [NUMERICAL]
# 	3 : RootMeanSquared [NUMERICAL]
# 	3 : Maximum [NUMERICAL]
# 	2 : TotalEnergy [NUMERICAL]
# 	1 : Entropy [NUMERICAL]
# 	1 : Energy [NUMERICAL]
#
# Attribute in nodes with depth <= 1:
# 	69 : Kurtosis [NUMERICAL]
# 	61 : Skewness [NUMERICAL]
# 	54 : Maximum [NUMERICAL]
# 	47 : Variance [NUMERICAL]
# 	46 : 90Percentile [NUMERICAL]
# 	43 : Minimum [NUMERICAL]
# 	42 : Range [NUMERICAL]
# 	41 : RobustMeanAbsoluteDeviation [NUMERICAL]
# 	36 : Mean [NUMERICAL]
# 	36 : 10Percentile [NUMERICAL]
# 	26 : Uniformity [NUMERICAL]
# 	26 : Median [NUMERICAL]
# 	25 : MeanAbsoluteDeviation [NUMERICAL]
# 	18 : Entropy [NUMERICAL]
# 	17 : InterquartileRange [NUMERICAL]
# 	10 : RootMeanSquared [NUMERICAL]
# 	8 : TotalEnergy [NUMERICAL]
# 	7 : Energy [NUMERICAL]
#
# Attribute in nodes with depth <= 2:
# 	149 : Kurtosis [NUMERICAL]
# 	135 : Skewness [NUMERICAL]
# 	122 : 90Percentile [NUMERICAL]
# 	113 : Minimum [NUMERICAL]
# 	104 : Variance [NUMERICAL]
# 	103 : Maximum [NUMERICAL]
# 	88 : 10Percentile [NUMERICAL]
# 	86 : Median [NUMERICAL]
# 	81 : Range [NUMERICAL]
# 	74 : RobustMeanAbsoluteDeviation [NUMERICAL]
# 	70 : Uniformity [NUMERICAL]
# 	66 : Mean [NUMERICAL]
# 	61 : MeanAbsoluteDeviation [NUMERICAL]
# 	50 : Entropy [NUMERICAL]
# 	42 : InterquartileRange [NUMERICAL]
# 	23 : RootMeanSquared [NUMERICAL]
# 	18 : TotalEnergy [NUMERICAL]
# 	16 : Energy [NUMERICAL]
#
# Attribute in nodes with depth <= 3:
# 	278 : Skewness [NUMERICAL]
# 	269 : 90Percentile [NUMERICAL]
# 	244 : Kurtosis [NUMERICAL]
# 	236 : Maximum [NUMERICAL]
# 	215 : Median [NUMERICAL]
# 	214 : 10Percentile [NUMERICAL]
# 	213 : Minimum [NUMERICAL]
# 	176 : Variance [NUMERICAL]
# 	163 : Range [NUMERICAL]
# 	147 : Uniformity [NUMERICAL]
# 	137 : RobustMeanAbsoluteDeviation [NUMERICAL]
# 	116 : MeanAbsoluteDeviation [NUMERICAL]
# 	115 : InterquartileRange [NUMERICAL]
# 	107 : Mean [NUMERICAL]
# 	106 : Entropy [NUMERICAL]
# 	63 : RootMeanSquared [NUMERICAL]
# 	49 : TotalEnergy [NUMERICAL]
# 	41 : Energy [NUMERICAL]
#
# Attribute in nodes with depth <= 5:
# 	552 : Skewness [NUMERICAL]
# 	490 : Kurtosis [NUMERICAL]
# 	483 : 90Percentile [NUMERICAL]
# 	444 : Maximum [NUMERICAL]
# 	423 : Median [NUMERICAL]
# 	405 : Minimum [NUMERICAL]
# 	393 : 10Percentile [NUMERICAL]
# 	330 : Variance [NUMERICAL]
# 	324 : Range [NUMERICAL]
# 	295 : Uniformity [NUMERICAL]
# 	275 : RobustMeanAbsoluteDeviation [NUMERICAL]
# 	230 : InterquartileRange [NUMERICAL]
# 	228 : Mean [NUMERICAL]
# 	225 : Entropy [NUMERICAL]
# 	203 : MeanAbsoluteDeviation [NUMERICAL]
# 	122 : RootMeanSquared [NUMERICAL]
# 	96 : TotalEnergy [NUMERICAL]
# 	87 : Energy [NUMERICAL]
#
# Condition type in nodes:
# 	5605 : HigherCondition
# Condition type in nodes with depth <= 0:
# 	204 : HigherCondition
# Condition type in nodes with depth <= 1:
# 	612 : HigherCondition
# Condition type in nodes with depth <= 2:
# 	1401 : HigherCondition
# Condition type in nodes with depth <= 3:
# 	2889 : HigherCondition
# Condition type in nodes with depth <= 5:
# 	5605 : HigherCondition
#
# Training logs:
# Number of iteration to final model: 204
# 	Iter:1 train-loss:1.287529 valid-loss:1.287480  train-accuracy:0.835415 valid-accuracy:0.836354
# 	Iter:2 train-loss:1.205699 valid-loss:1.206740  train-accuracy:0.838181 valid-accuracy:0.834374
# 	Iter:3 train-loss:1.138463 valid-loss:1.140552  train-accuracy:0.840541 valid-accuracy:0.838446
# 	Iter:4 train-loss:1.078174 valid-loss:1.079800  train-accuracy:0.843586 valid-accuracy:0.841267
# 	Iter:5 train-loss:1.029366 valid-loss:1.031657  train-accuracy:0.847350 valid-accuracy:0.844474
# 	Iter:6 train-loss:0.985085 valid-loss:0.988606  train-accuracy:0.848721 valid-accuracy:0.844922
# 	Iter:16 train-loss:0.755172 valid-loss:0.764713  train-accuracy:0.859012 valid-accuracy:0.853648
# 	Iter:26 train-loss:0.678622 valid-loss:0.693671  train-accuracy:0.864732 valid-accuracy:0.854542
# 	Iter:36 train-loss:0.642795 valid-loss:0.663133  train-accuracy:0.868760 valid-accuracy:0.856885
# 	Iter:46 train-loss:0.623459 valid-loss:0.650018  train-accuracy:0.871148 valid-accuracy:0.859845
# 	Iter:56 train-loss:0.610235 valid-loss:0.643232  train-accuracy:0.873412 valid-accuracy:0.861249
# 	Iter:66 train-loss:0.599981 valid-loss:0.638618  train-accuracy:0.874966 valid-accuracy:0.860816
# 	Iter:76 train-loss:0.589942 valid-loss:0.634310  train-accuracy:0.877357 valid-accuracy:0.861495
# 	Iter:86 train-loss:0.582084 valid-loss:0.631633  train-accuracy:0.878714 valid-accuracy:0.862526
# 	Iter:96 train-loss:0.574235 valid-loss:0.629817  train-accuracy:0.880691 valid-accuracy:0.862296
# 	Iter:106 train-loss:0.568711 valid-loss:0.628366  train-accuracy:0.882183 valid-accuracy:0.864802
# 	Iter:116 train-loss:0.562982 valid-loss:0.626172  train-accuracy:0.883358 valid-accuracy:0.864221
# 	Iter:126 train-loss:0.558051 valid-loss:0.625330  train-accuracy:0.884418 valid-accuracy:0.864594
# 	Iter:136 train-loss:0.553234 valid-loss:0.624534  train-accuracy:0.885726 valid-accuracy:0.864887
# 	Iter:146 train-loss:0.548246 valid-loss:0.622915  train-accuracy:0.886916 valid-accuracy:0.865795
# 	Iter:156 train-loss:0.541906 valid-loss:0.621938  train-accuracy:0.888460 valid-accuracy:0.866223
# 	Iter:166 train-loss:0.538414 valid-loss:0.621066  train-accuracy:0.889046 valid-accuracy:0.866583
# 	Iter:176 train-loss:0.533799 valid-loss:0.621322  train-accuracy:0.890016 valid-accuracy:0.866484
# 	Iter:186 train-loss:0.530014 valid-loss:0.621375  train-accuracy:0.891052 valid-accuracy:0.866641
# 	Iter:196 train-loss:0.524659 valid-loss:0.620318  train-accuracy:0.892185 valid-accuracy:0.867550
# 	Iter:206 train-loss:0.519651 valid-loss:0.620257  train-accuracy:0.893673 valid-accuracy:0.866838
# 	Iter:216 train-loss:0.515877 valid-loss:0.620738  train-accuracy:0.894888 valid-accuracy:0.867153
# 	Iter:226 train-loss:0.511374 valid-loss:0.620464  train-accuracy:0.896385 valid-accuracy:0.867828

# %%
# Model features
model.make_inspector().features()
# Out:
# ["10Percentile" (1; #0),
#  "90Percentile" (1; #1),
#  "Energy" (1; #2),
#  "Entropy" (1; #3),
#  "InterquartileRange" (1; #4),
#  "Kurtosis" (1; #5),
#  "Maximum" (1; #6),
#  "Mean" (1; #7),
#  "MeanAbsoluteDeviation" (1; #8),
#  "Median" (1; #9),
#  "Minimum" (1; #10),
#  "Range" (1; #11),
#  "RobustMeanAbsoluteDeviation" (1; #12),
#  "RootMeanSquared" (1; #13),
#  "Skewness" (1; #14),
#  "TotalEnergy" (1; #15),
#  "Uniformity" (1; #16),
#  "Variance" (1; #17)]

# %%
# Feature importance
model.make_inspector().variable_importances()
# Out:
# {'INV_MEAN_MIN_DEPTH': [("90Percentile" (1; #1), 0.21423310354482963),
#   ("Minimum" (1; #10), 0.21128494039596238),
#   ("Kurtosis" (1; #5), 0.2099407639056613),
#   ("Skewness" (1; #14), 0.2060402192571366),
#   ("Variance" (1; #17), 0.20250897065755116),
#   ("Maximum" (1; #6), 0.2018408448521443),
#   ("10Percentile" (1; #0), 0.19862761605290027),
#   ("Median" (1; #9), 0.19729221656643198),
#   ("Range" (1; #11), 0.19554466150035307),
#   ("RobustMeanAbsoluteDeviation" (1; #12), 0.18942419119703985),
#   ("Mean" (1; #7), 0.18841012925681702),
#   ("Uniformity" (1; #16), 0.18783471534170784),
#   ("InterquartileRange" (1; #4), 0.18538767242524745),
#   ("MeanAbsoluteDeviation" (1; #8), 0.18429247429082282),
#   ("Entropy" (1; #3), 0.18061700814185208),
#   ("RootMeanSquared" (1; #13), 0.17722384481291487),
#   ("TotalEnergy" (1; #15), 0.17551601868190317),
#   ("Energy" (1; #2), 0.17447280229655396)],
#  'SUM_SCORE': [("90Percentile" (1; #1), 72180.16719955268),
#   ("Mean" (1; #7), 38771.95402861623),
#   ("Minimum" (1; #10), 11126.528408725164),
#   ("10Percentile" (1; #0), 10521.533679528457),
#   ("Kurtosis" (1; #5), 9138.869584855829),
#   ("TotalEnergy" (1; #15), 8745.415426601498),
#   ("Maximum" (1; #6), 6859.403213339657),
#   ("RootMeanSquared" (1; #13), 5919.633176627235),
#   ("Median" (1; #9), 4495.646464742742),
#   ("Energy" (1; #2), 4489.926163818419),
#   ("Skewness" (1; #14), 4289.631048222578),
#   ("Uniformity" (1; #16), 3130.479766813052),
#   ("InterquartileRange" (1; #4), 3125.1879759140575),
#   ("RobustMeanAbsoluteDeviation" (1; #12), 2911.5785831361413),
#   ("Range" (1; #11), 2840.6342918946943),
#   ("Variance" (1; #17), 2127.4650475949074),
#   ("MeanAbsoluteDeviation" (1; #8), 1612.0880443409415),
#   ("Entropy" (1; #3), 1090.8229410910924)],
#  'NUM_AS_ROOT': [("90Percentile" (1; #1), 29.0),
#   ("Minimum" (1; #10), 26.0),
#   ("Variance" (1; #17), 24.0),
#   ("Kurtosis" (1; #5), 20.0),
#   ("Median" (1; #9), 14.0),
#   ("Skewness" (1; #14), 14.0),
#   ("10Percentile" (1; #0), 13.0),
#   ("Mean" (1; #7), 13.0),
#   ("RobustMeanAbsoluteDeviation" (1; #12), 11.0),
#   ("InterquartileRange" (1; #4), 9.0),
#   ("MeanAbsoluteDeviation" (1; #8), 8.0),
#   ("Range" (1; #11), 7.0),
#   ("Uniformity" (1; #16), 6.0),
#   ("Maximum" (1; #6), 3.0),
#   ("RootMeanSquared" (1; #13), 3.0),
#   ("TotalEnergy" (1; #15), 2.0),
#   ("Energy" (1; #2), 1.0),
#   ("Entropy" (1; #3), 1.0)],
#  'NUM_NODES': [("Skewness" (1; #14), 552.0),
#   ("Kurtosis" (1; #5), 490.0),
#   ("90Percentile" (1; #1), 483.0),
#   ("Maximum" (1; #6), 444.0),
#   ("Median" (1; #9), 423.0),
#   ("Minimum" (1; #10), 405.0),
#   ("10Percentile" (1; #0), 393.0),
#   ("Variance" (1; #17), 330.0),
#   ("Range" (1; #11), 324.0),
#   ("Uniformity" (1; #16), 295.0),
#   ("RobustMeanAbsoluteDeviation" (1; #12), 275.0),
#   ("InterquartileRange" (1; #4), 230.0),
#   ("Mean" (1; #7), 228.0),
#   ("Entropy" (1; #3), 225.0),
#   ("MeanAbsoluteDeviation" (1; #8), 203.0),
#   ("RootMeanSquared" (1; #13), 122.0),
#   ("TotalEnergy" (1; #15), 96.0),
#   ("Energy" (1; #2), 87.0)]}

# %%
# Model self evaluation
model.make_inspector().evaluation()
# Out:
# Evaluation(num_examples=None, accuracy=0.8681342601776123, loss=0.6201443076133728, rmse=None, ndcg=None, aucs=None, auuc=None, qini=None)

# %%
logs = model.make_inspector().training_logs()

plt.figure(figsize=(12, 4))
plt.subplot(1, 2, 1)
plt.plot([log.num_trees for log in logs], [log.evaluation.accuracy for log in logs])
plt.xlabel("Number of trees")
plt.ylabel("Accuracy (out-of-bag)")
plt.subplot(1, 2, 2)
plt.plot([log.num_trees for log in logs], [log.evaluation.loss for log in logs])
plt.xlabel("Number of trees")
plt.ylabel("Logloss (out-of-bag)")
plt.show()

# %% [markdown]
# Calculate the score of our hold-out validation dataset

# %%
predictions = model.predict(val_ds)
y_true      = validation_data["label"]

from sklearn.metrics import roc_auc_score
ROC_AUC = roc_auc_score(y_true, predictions)
print("The ROC AUC score is %.5f" % ROC_AUC )
# Out:
#  1/34 [..............................] - ETA: 2s
# 11/34 [========>.....................] - ETA: 0s
# 23/34 [===================>..........] - ETA: 0s
# 34/34 [==============================] - 0s 5ms/step
# The ROC AUC score is 0.94095

# %%
# Compute binary classification metrics with sklearn
import numpy as np
from sklearn.metrics import (
    accuracy_score,
    precision_score,
    recall_score,
    f1_score,
    roc_auc_score,
    average_precision_score,
    confusion_matrix,
    classification_report,
    matthews_corrcoef,
    log_loss,
    brier_score_loss,
)

# Get predictions (probabilities or class labels)
preds = model.predict(test_ds)
# If model outputs probabilities, convert to labels by threshold 0.5
if preds.ndim == 2:
    # For TFDF classification, preds may be class probabilities with shape (N, 2)
    if preds.shape[1] == 2:
        pos_probs = preds[:, 1]
    else:
        # If single-probability column (positive class)
        pos_probs = preds[:, -1]
    y_pred = (pos_probs >= 0.5).astype(int)
else:
    # Already class labels
    y_pred = preds.astype(int)
    pos_probs = None

# Ground truth labels (must be 0/1 integers)
y_true = test_data["label"].astype(int).to_numpy()

# Core metrics
metrics = {}
metrics["accuracy"] = accuracy_score(y_true, y_pred)
metrics["precision"] = precision_score(y_true, y_pred, zero_division=0)
metrics["recall"] = recall_score(y_true, y_pred, zero_division=0)
metrics["f1"] = f1_score(y_true, y_pred, zero_division=0)
metrics["mcc"] = matthews_corrcoef(y_true, y_pred)

# Probabilistic metrics (only if we have probabilities)
if pos_probs is not None:
    metrics["roc_auc"] = roc_auc_score(y_true, pos_probs)
    metrics["pr_auc"] = average_precision_score(y_true, pos_probs)
    metrics["log_loss"] = log_loss(y_true, pos_probs, labels=[0,1])
    metrics["brier_score"] = brier_score_loss(y_true, pos_probs)

# Confusion matrix and detailed report
cm = confusion_matrix(y_true, y_pred, labels=[0,1])
report = classification_report(y_true, y_pred, digits=4)

print("Sklearn binary metrics:")
for k, v in metrics.items():
    print(f"{k}: {v:.4f}")
print("\nConfusion matrix:\n", cm)
print("\nClassification report:\n", report)
# Out:
#  1/68 [..............................] - ETA: 4s
# 12/68 [====>.........................] - ETA: 0s
# 23/68 [=========>....................] - ETA: 0s
# 34/68 [==============>...............] - ETA: 0s
# 45/68 [==================>...........] - ETA: 0s
# 56/68 [=======================>......] - ETA: 0s
# 68/68 [==============================] - ETA: 0s
# 68/68 [==============================] - 0s 5ms/step
# Sklearn binary metrics:
# accuracy: 0.8900
# precision: 0.3390
# recall: 0.8352
# f1: 0.4822
# mcc: 0.4882
# roc_auc: 0.9400
# pr_auc: 0.6497
# log_loss: 0.2774
# brier_score: 0.0832
#
# Confusion matrix:
#  [[56434  6720]
#  [  680  3446]]
#
# Classification report:
#                precision    recall  f1-score   support
#
#            0     0.9881    0.8936    0.9385     63154
#            1     0.3390    0.8352    0.4822      4126
#
#     accuracy                         0.8900     67280
#    macro avg     0.6635    0.8644    0.7103     67280
# weighted avg     0.9483    0.8900    0.9105     67280
