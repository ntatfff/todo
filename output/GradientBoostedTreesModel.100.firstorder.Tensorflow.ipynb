# %%
# Import packages and modules
import numpy  as np
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow_decision_forests as tfdf

from sklearn.model_selection import train_test_split
# Out:
# 2026-07-04 07:35:03.755668: I tensorflow/core/util/port.cc:113] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2026-07-04 07:35:03.802939: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2026-07-04 07:35:09.451237: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
# Check the version of TensorFlow Decision Forests
print("Found TensorFlow Decision Forests v" + tfdf.__version__)
# Out:
# Found TensorFlow Decision Forests v1.9.1

# %%
datasetPath = 'dataset/firstorder/kernel5-radius5/dataset.csv'

# %%
# Parameters
datasetPath = "dataset/firstorder/kernel5-radius5/100.dataset.csv"

# %%
# train/validation/test = 70/10/20
dataset = pd.read_csv(datasetPath)

train_data, temp_data = train_test_split(dataset, test_size=0.3, random_state=42)
validation_data, test_data = train_test_split(temp_data, test_size=2/3, random_state=42)

# %%
from sklearn.utils.class_weight import compute_class_weight

# tinh class weight tren tap train
classes = np.array([0, 1])
weights = compute_class_weight(class_weight="balanced", classes=classes, y=train_data["label"])
class_weight = {0: weights[0], 1: weights[1]}

# gan sample_weight cho tung dong
train_data["sample_weight"] = train_data["label"].map(class_weight)
validation_data["sample_weight"] = validation_data["label"].map(class_weight)
test_data["sample_weight"] = test_data["label"].map(class_weight)

# Convert the dataset into a TensorFlow dataset.
train_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    train_data, label="label", weight="sample_weight"
)         
val_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    validation_data, label="label", weight="sample_weight"
)
test_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    test_data, label="label", weight="sample_weight"
)
# Out:
# 2026-07-04 07:35:21.530092: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:984] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2026-07-04 07:35:21.531214: W tensorflow/core/common_runtime/gpu/gpu_device.cc:2251] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...

# %%
import keras

# %%
# %%time

# Train a Gradient Boosted Trees model.
model = tfdf.keras.GradientBoostedTreesModel()

# Add evaluation metrics
model.compile(
    metrics=["accuracy"]
)
model.fit(x=train_ds)

# # Train a Gradient Boosted Trees model.
# model = tfdf.keras.GradientBoostedTreesModel(num_trees=1500)
# model.fit(train_ds)
# Out:
# Use /tmp/tmp8sjfhwbe as temporary training directory
# Reading training dataset...
# [WARNING 26-07-04 07:35:21.6767 UTC gradient_boosted_trees.cc:1840] "goss_alpha" set but "sampling_method" not equal to "GOSS".
# [WARNING 26-07-04 07:35:21.6768 UTC gradient_boosted_trees.cc:1851] "goss_beta" set but "sampling_method" not equal to "GOSS".
# [WARNING 26-07-04 07:35:21.6768 UTC gradient_boosted_trees.cc:1865] "selective_gradient_boosting_ratio" set but "sampling_method" not equal to "SELGB".
# Training dataset read in 0:00:02.840946. Found 78712 examples.
# Training model...
# Model trained in 0:00:10.154694
# Compiling model...
# [INFO 26-07-04 07:35:34.7029 UTC kernel.cc:1233] Loading model from path /tmp/tmp8sjfhwbe/model/ with prefix 901b78e8c5ed4d17
# [INFO 26-07-04 07:35:34.7099 UTC quick_scorer_extended.cc:911] The binary was compiled without AVX2 support, but your CPU supports it. Enable it for faster model inference.
# [INFO 26-07-04 07:35:34.7104 UTC abstract_model.cc:1362] Engine "GradientBoostedTreesQuickScorerExtended" built
# [INFO 26-07-04 07:35:34.7104 UTC kernel.cc:1061] Use fast generic engine
# Model compiled.
# CPU times: user 1min 18s, sys: 1.92 s, total: 1min 20s
# Wall time: 16.1 s

# %%
# Evaluate the model
evaluate = model.evaluate(val_ds, return_dict=True)
print()

for name, value in evaluate.items():
    print(f"{name}: {value:.4f}")
# Out:
# WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
#  1/12 [=>............................] - ETA: 47s - loss: 0.0000e+00 - accuracy: 0.9150
# 12/12 [==============================] - 4s 5ms/step - loss: 0.0000e+00 - accuracy: 0.9025
# loss: 0.0000
# accuracy: 0.9025

# %%
# Model Summary
model.summary()
# Out:
# Model: "gradient_boosted_trees_model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
# =================================================================
# Total params: 1 (1.00 Byte)
# Trainable params: 0 (0.00 Byte)
# Non-trainable params: 1 (1.00 Byte)
# _________________________________________________________________
# Type: "GRADIENT_BOOSTED_TREES"
# Task: CLASSIFICATION
# Label: "__LABEL"
#
# Input Features (18):
# 	10Percentile
# 	90Percentile
# 	Energy
# 	Entropy
# 	InterquartileRange
# 	Kurtosis
# 	Maximum
# 	Mean
# 	MeanAbsoluteDeviation
# 	Median
# 	Minimum
# 	Range
# 	RobustMeanAbsoluteDeviation
# 	RootMeanSquared
# 	Skewness
# 	TotalEnergy
# 	Uniformity
# 	Variance
#
# Trained with weights
#
# Variable Importance: INV_MEAN_MIN_DEPTH:
#     1.                "90Percentile"  0.219374 ################
#     2.                     "Maximum"  0.213165 #############
#     3.                      "Median"  0.213050 #############
#     4.                    "Skewness"  0.211368 #############
#     5.                     "Minimum"  0.204798 ##########
#     6.                "10Percentile"  0.198528 ########
#     7.                  "Uniformity"  0.197546 #######
#     8.                    "Variance"  0.194141 ######
#     9.                       "Range"  0.189377 ####
#    10.                    "Kurtosis"  0.189099 ####
#    11.                        "Mean"  0.188098 ####
#    12. "RobustMeanAbsoluteDeviation"  0.187439 ####
#    13.                     "Entropy"  0.185533 ###
#    14.                 "TotalEnergy"  0.183771 ##
#    15.                      "Energy"  0.181234 #
#    16.             "RootMeanSquared"  0.179860 #
#    17.          "InterquartileRange"  0.177934
#    18.       "MeanAbsoluteDeviation"  0.176546
#
# Variable Importance: NUM_AS_ROOT:
#     1.                "90Percentile" 20.000000 ################
#     2.                      "Median" 15.000000 ###########
#     3.                     "Minimum" 14.000000 ##########
#     4.                    "Skewness" 14.000000 ##########
#     5.                "10Percentile" 12.000000 #########
#     6.                    "Variance" 11.000000 ########
#     7.                 "TotalEnergy"  8.000000 #####
#     8.                  "Uniformity"  8.000000 #####
#     9. "RobustMeanAbsoluteDeviation"  7.000000 #####
#    10.                        "Mean"  6.000000 ####
#    11.                     "Entropy"  5.000000 ###
#    12.                      "Energy"  4.000000 ##
#    13.                    "Kurtosis"  4.000000 ##
#    14.             "RootMeanSquared"  4.000000 ##
#    15.                     "Maximum"  3.000000 #
#    16.                       "Range"  1.000000
#
# Variable Importance: NUM_NODES:
#     1.                    "Skewness" 343.000000 ################
#     2.                      "Median" 331.000000 ###############
#     3.                "90Percentile" 316.000000 ##############
#     4.                     "Maximum" 312.000000 ##############
#     5.                     "Minimum" 299.000000 #############
#     6.                    "Kurtosis" 250.000000 ##########
#     7.                  "Uniformity" 243.000000 ##########
#     8.                       "Range" 220.000000 ########
#     9.                    "Variance" 201.000000 #######
#    10.                "10Percentile" 192.000000 #######
#    11. "RobustMeanAbsoluteDeviation" 172.000000 #####
#    12.                        "Mean" 171.000000 #####
#    13.                     "Entropy" 162.000000 #####
#    14.          "InterquartileRange" 127.000000 ###
#    15.       "MeanAbsoluteDeviation" 107.000000 ##
#    16.                 "TotalEnergy" 90.000000 #
#    17.             "RootMeanSquared" 78.000000
#    18.                      "Energy" 72.000000
#
# Variable Importance: SUM_SCORE:
#     1.                 "TotalEnergy" 15272.611014 ################
#     2.                     "Maximum" 7585.339586 #######
#     3.                     "Minimum" 6914.756190 ######
#     4.                "90Percentile" 6763.525486 ######
#     5.                      "Energy" 6566.034776 ######
#     6.             "RootMeanSquared" 3786.644746 ###
#     7.                       "Range" 2668.345129 ##
#     8.                        "Mean" 2521.327939 #
#     9.                    "Kurtosis" 2072.628665 #
#    10.                      "Median" 2008.796308 #
#    11.       "MeanAbsoluteDeviation" 1684.303019 #
#    12.                    "Skewness" 1663.196785
#    13.                  "Uniformity" 1385.050731
#    14.                "10Percentile" 1237.510763
#    15. "RobustMeanAbsoluteDeviation" 1032.054581
#    16.                    "Variance" 1003.863502
#    17.          "InterquartileRange" 971.462632
#    18.                     "Entropy" 771.545055
#
#
#
# Loss: BINOMIAL_LOG_LIKELIHOOD
# Validation loss value: 0.639752
# Number of trees per iteration: 1
# Node format: NOT_SET
# Number of trees: 136
# Total number of nodes: 7508
#
# Number of nodes by tree:
# Count: 136 Average: 55.2059 StdDev: 6.82245
# Min: 37 Max: 63 Ignored: 0
# ----------------------------------------------
# [ 37, 38)  1   0.74%   0.74%
# [ 38, 39)  0   0.00%   0.74%
# [ 39, 41)  0   0.00%   0.74%
# [ 41, 42)  4   2.94%   3.68% ##
# [ 42, 43)  0   0.00%   3.68%
# [ 43, 45)  8   5.88%   9.56% ###
# [ 45, 46)  5   3.68%  13.24% ##
# [ 46, 47)  0   0.00%  13.24%
# [ 47, 49) 10   7.35%  20.59% ####
# [ 49, 50)  8   5.88%  26.47% ###
# [ 50, 51)  0   0.00%  26.47%
# [ 51, 53)  4   2.94%  29.41% ##
# [ 53, 54)  7   5.15%  34.56% ###
# [ 54, 55)  0   0.00%  34.56%
# [ 55, 57) 13   9.56%  44.12% ######
# [ 57, 58) 17  12.50%  56.62% #######
# [ 58, 59)  0   0.00%  56.62%
# [ 59, 61) 14  10.29%  66.91% ######
# [ 61, 62) 22  16.18%  83.09% ##########
# [ 62, 63] 23  16.91% 100.00% ##########
#
# Depth by leafs:
# Count: 3822 Average: 4.89456 StdDev: 0.391734
# Min: 2 Max: 5 Ignored: 0
# ----------------------------------------------
# [ 2, 3)   14   0.37%   0.37%
# [ 3, 4)   71   1.86%   2.22%
# [ 4, 5)  219   5.73%   7.95% #
# [ 5, 5] 3518  92.05% 100.00% ##########
#
# Number of training obs by leaf:
# Count: 3822 Average: 2520.73 StdDev: 7872.9
# Min: 5 Max: 69470 Ignored: 0
# ----------------------------------------------
# [     5,  3478) 3287  86.00%  86.00% ##########
# [  3478,  6951)  209   5.47%  91.47% #
# [  6951, 10424)   98   2.56%  94.03%
# [ 10424, 13898)   44   1.15%  95.19%
# [ 13898, 17371)   36   0.94%  96.13%
# [ 17371, 20844)   27   0.71%  96.83%
# [ 20844, 24318)   15   0.39%  97.23%
# [ 24318, 27791)   15   0.39%  97.62%
# [ 27791, 31264)   11   0.29%  97.91%
# [ 31264, 34738)    9   0.24%  98.14%
# [ 34738, 38211)    7   0.18%  98.33%
# [ 38211, 41684)    8   0.21%  98.53%
# [ 41684, 45157)    8   0.21%  98.74%
# [ 45157, 48631)   13   0.34%  99.08%
# [ 48631, 52104)    6   0.16%  99.24%
# [ 52104, 55577)    8   0.21%  99.45%
# [ 55577, 59051)    8   0.21%  99.66%
# [ 59051, 62524)    4   0.10%  99.76%
# [ 62524, 65997)    6   0.16%  99.92%
# [ 65997, 69470]    3   0.08% 100.00%
#
# Attribute in nodes:
# 	343 : Skewness [NUMERICAL]
# 	331 : Median [NUMERICAL]
# 	316 : 90Percentile [NUMERICAL]
# 	312 : Maximum [NUMERICAL]
# 	299 : Minimum [NUMERICAL]
# 	250 : Kurtosis [NUMERICAL]
# 	243 : Uniformity [NUMERICAL]
# 	220 : Range [NUMERICAL]
# 	201 : Variance [NUMERICAL]
# 	192 : 10Percentile [NUMERICAL]
# 	172 : RobustMeanAbsoluteDeviation [NUMERICAL]
# 	171 : Mean [NUMERICAL]
# 	162 : Entropy [NUMERICAL]
# 	127 : InterquartileRange [NUMERICAL]
# 	107 : MeanAbsoluteDeviation [NUMERICAL]
# 	90 : TotalEnergy [NUMERICAL]
# 	78 : RootMeanSquared [NUMERICAL]
# 	72 : Energy [NUMERICAL]
#
# Attribute in nodes with depth <= 0:
# 	20 : 90Percentile [NUMERICAL]
# 	15 : Median [NUMERICAL]
# 	14 : Skewness [NUMERICAL]
# 	14 : Minimum [NUMERICAL]
# 	12 : 10Percentile [NUMERICAL]
# 	11 : Variance [NUMERICAL]
# 	8 : Uniformity [NUMERICAL]
# 	8 : TotalEnergy [NUMERICAL]
# 	7 : RobustMeanAbsoluteDeviation [NUMERICAL]
# 	6 : Mean [NUMERICAL]
# 	5 : Entropy [NUMERICAL]
# 	4 : RootMeanSquared [NUMERICAL]
# 	4 : Kurtosis [NUMERICAL]
# 	4 : Energy [NUMERICAL]
# 	3 : Maximum [NUMERICAL]
# 	1 : Range [NUMERICAL]
#
# Attribute in nodes with depth <= 1:
# 	55 : Maximum [NUMERICAL]
# 	49 : Skewness [NUMERICAL]
# 	36 : Median [NUMERICAL]
# 	35 : 90Percentile [NUMERICAL]
# 	32 : Uniformity [NUMERICAL]
# 	27 : Minimum [NUMERICAL]
# 	26 : 10Percentile [NUMERICAL]
# 	23 : Variance [NUMERICAL]
# 	19 : RobustMeanAbsoluteDeviation [NUMERICAL]
# 	17 : Kurtosis [NUMERICAL]
# 	16 : Range [NUMERICAL]
# 	16 : Entropy [NUMERICAL]
# 	14 : Mean [NUMERICAL]
# 	14 : Energy [NUMERICAL]
# 	10 : TotalEnergy [NUMERICAL]
# 	10 : RootMeanSquared [NUMERICAL]
# 	5 : InterquartileRange [NUMERICAL]
# 	4 : MeanAbsoluteDeviation [NUMERICAL]
#
# Attribute in nodes with depth <= 2:
# 	97 : Maximum [NUMERICAL]
# 	90 : 90Percentile [NUMERICAL]
# 	86 : Median [NUMERICAL]
# 	84 : Skewness [NUMERICAL]
# 	71 : Minimum [NUMERICAL]
# 	63 : Uniformity [NUMERICAL]
# 	55 : Kurtosis [NUMERICAL]
# 	53 : Variance [NUMERICAL]
# 	53 : Range [NUMERICAL]
# 	50 : 10Percentile [NUMERICAL]
# 	49 : Mean [NUMERICAL]
# 	36 : Entropy [NUMERICAL]
# 	34 : RobustMeanAbsoluteDeviation [NUMERICAL]
# 	28 : TotalEnergy [NUMERICAL]
# 	27 : Energy [NUMERICAL]
# 	23 : MeanAbsoluteDeviation [NUMERICAL]
# 	21 : RootMeanSquared [NUMERICAL]
# 	18 : InterquartileRange [NUMERICAL]
#
# Attribute in nodes with depth <= 3:
# 	183 : Median [NUMERICAL]
# 	175 : Skewness [NUMERICAL]
# 	175 : Maximum [NUMERICAL]
# 	162 : Minimum [NUMERICAL]
# 	162 : 90Percentile [NUMERICAL]
# 	129 : Uniformity [NUMERICAL]
# 	119 : Kurtosis [NUMERICAL]
# 	110 : Variance [NUMERICAL]
# 	110 : Range [NUMERICAL]
# 	98 : Mean [NUMERICAL]
# 	93 : 10Percentile [NUMERICAL]
# 	92 : RobustMeanAbsoluteDeviation [NUMERICAL]
# 	78 : Entropy [NUMERICAL]
# 	57 : MeanAbsoluteDeviation [NUMERICAL]
# 	52 : TotalEnergy [NUMERICAL]
# 	49 : InterquartileRange [NUMERICAL]
# 	42 : RootMeanSquared [NUMERICAL]
# 	41 : Energy [NUMERICAL]
#
# Attribute in nodes with depth <= 5:
# 	343 : Skewness [NUMERICAL]
# 	331 : Median [NUMERICAL]
# 	316 : 90Percentile [NUMERICAL]
# 	312 : Maximum [NUMERICAL]
# 	299 : Minimum [NUMERICAL]
# 	250 : Kurtosis [NUMERICAL]
# 	243 : Uniformity [NUMERICAL]
# 	220 : Range [NUMERICAL]
# 	201 : Variance [NUMERICAL]
# 	192 : 10Percentile [NUMERICAL]
# 	172 : RobustMeanAbsoluteDeviation [NUMERICAL]
# 	171 : Mean [NUMERICAL]
# 	162 : Entropy [NUMERICAL]
# 	127 : InterquartileRange [NUMERICAL]
# 	107 : MeanAbsoluteDeviation [NUMERICAL]
# 	90 : TotalEnergy [NUMERICAL]
# 	78 : RootMeanSquared [NUMERICAL]
# 	72 : Energy [NUMERICAL]
#
# Condition type in nodes:
# 	3686 : HigherCondition
# Condition type in nodes with depth <= 0:
# 	136 : HigherCondition
# Condition type in nodes with depth <= 1:
# 	408 : HigherCondition
# Condition type in nodes with depth <= 2:
# 	938 : HigherCondition
# Condition type in nodes with depth <= 3:
# 	1927 : HigherCondition
# Condition type in nodes with depth <= 5:
# 	3686 : HigherCondition
#
# Training logs:
# Number of iteration to final model: 136
# 	Iter:1 train-loss:1.289055 valid-loss:1.290124  train-accuracy:0.832493 valid-accuracy:0.823858
# 	Iter:2 train-loss:1.208356 valid-loss:1.209538  train-accuracy:0.829701 valid-accuracy:0.824817
# 	Iter:3 train-loss:1.140757 valid-loss:1.143221  train-accuracy:0.837344 valid-accuracy:0.827569
# 	Iter:4 train-loss:1.083434 valid-loss:1.087307  train-accuracy:0.834245 valid-accuracy:0.824863
# 	Iter:5 train-loss:1.035456 valid-loss:1.038296  train-accuracy:0.837182 valid-accuracy:0.830081
# 	Iter:6 train-loss:0.993749 valid-loss:0.996835  train-accuracy:0.836787 valid-accuracy:0.829952
# 	Iter:16 train-loss:0.770891 valid-loss:0.777299  train-accuracy:0.848152 valid-accuracy:0.842189
# 	Iter:26 train-loss:0.694184 valid-loss:0.709396  train-accuracy:0.854965 valid-accuracy:0.849451
# 	Iter:36 train-loss:0.650477 valid-loss:0.681968  train-accuracy:0.862070 valid-accuracy:0.847367
# 	Iter:46 train-loss:0.622239 valid-loss:0.667535  train-accuracy:0.867773 valid-accuracy:0.849187
# 	Iter:56 train-loss:0.600163 valid-loss:0.658091  train-accuracy:0.873174 valid-accuracy:0.853959
# 	Iter:66 train-loss:0.585286 valid-loss:0.652928  train-accuracy:0.876222 valid-accuracy:0.856043
# 	Iter:76 train-loss:0.572279 valid-loss:0.649511  train-accuracy:0.880221 valid-accuracy:0.856923
# 	Iter:86 train-loss:0.559216 valid-loss:0.647348  train-accuracy:0.883768 valid-accuracy:0.854575
# 	Iter:96 train-loss:0.546314 valid-loss:0.645226  train-accuracy:0.887373 valid-accuracy:0.851361
# 	Iter:106 train-loss:0.537226 valid-loss:0.643798  train-accuracy:0.889581 valid-accuracy:0.855401
# 	Iter:116 train-loss:0.526490 valid-loss:0.642703  train-accuracy:0.893497 valid-accuracy:0.857486
# 	Iter:126 train-loss:0.516352 valid-loss:0.640960  train-accuracy:0.897148 valid-accuracy:0.859171
# 	Iter:136 train-loss:0.503801 valid-loss:0.639752  train-accuracy:0.901051 valid-accuracy:0.860654
# 	Iter:146 train-loss:0.493773 valid-loss:0.642692  train-accuracy:0.904539 valid-accuracy:0.857703
# 	Iter:156 train-loss:0.486489 valid-loss:0.641903  train-accuracy:0.906961 valid-accuracy:0.858109
# 	Iter:166 train-loss:0.475341 valid-loss:0.643160  train-accuracy:0.910073 valid-accuracy:0.854752

# %%
# Model features
model.make_inspector().features()
# Out:
# ["10Percentile" (1; #0),
#  "90Percentile" (1; #1),
#  "Energy" (1; #2),
#  "Entropy" (1; #3),
#  "InterquartileRange" (1; #4),
#  "Kurtosis" (1; #5),
#  "Maximum" (1; #6),
#  "Mean" (1; #7),
#  "MeanAbsoluteDeviation" (1; #8),
#  "Median" (1; #9),
#  "Minimum" (1; #10),
#  "Range" (1; #11),
#  "RobustMeanAbsoluteDeviation" (1; #12),
#  "RootMeanSquared" (1; #13),
#  "Skewness" (1; #14),
#  "TotalEnergy" (1; #15),
#  "Uniformity" (1; #16),
#  "Variance" (1; #17)]

# %%
# Feature importance
model.make_inspector().variable_importances()
# Out:
# {'INV_MEAN_MIN_DEPTH': [("90Percentile" (1; #1), 0.21937427360785366),
#   ("Maximum" (1; #6), 0.21316480370804006),
#   ("Median" (1; #9), 0.21304996479108784),
#   ("Skewness" (1; #14), 0.2113679754733742),
#   ("Minimum" (1; #10), 0.2047982393080866),
#   ("10Percentile" (1; #0), 0.19852819047643283),
#   ("Uniformity" (1; #16), 0.19754625839863152),
#   ("Variance" (1; #17), 0.1941413742624114),
#   ("Range" (1; #11), 0.18937738575055565),
#   ("Kurtosis" (1; #5), 0.18909855205722453),
#   ("Mean" (1; #7), 0.1880975559028945),
#   ("RobustMeanAbsoluteDeviation" (1; #12), 0.1874388747736006),
#   ("Entropy" (1; #3), 0.1855331581238493),
#   ("TotalEnergy" (1; #15), 0.18377060055262848),
#   ("Energy" (1; #2), 0.18123386481179976),
#   ("RootMeanSquared" (1; #13), 0.17986033270116233),
#   ("InterquartileRange" (1; #4), 0.17793422679804322),
#   ("MeanAbsoluteDeviation" (1; #8), 0.1765458711817421)],
#  'NUM_AS_ROOT': [("90Percentile" (1; #1), 20.0),
#   ("Median" (1; #9), 15.0),
#   ("Minimum" (1; #10), 14.0),
#   ("Skewness" (1; #14), 14.0),
#   ("10Percentile" (1; #0), 12.0),
#   ("Variance" (1; #17), 11.0),
#   ("TotalEnergy" (1; #15), 8.0),
#   ("Uniformity" (1; #16), 8.0),
#   ("RobustMeanAbsoluteDeviation" (1; #12), 7.0),
#   ("Mean" (1; #7), 6.0),
#   ("Entropy" (1; #3), 5.0),
#   ("Energy" (1; #2), 4.0),
#   ("Kurtosis" (1; #5), 4.0),
#   ("RootMeanSquared" (1; #13), 4.0),
#   ("Maximum" (1; #6), 3.0),
#   ("Range" (1; #11), 1.0)],
#  'SUM_SCORE': [("TotalEnergy" (1; #15), 15272.611014361592),
#   ("Maximum" (1; #6), 7585.339585931534),
#   ("Minimum" (1; #10), 6914.756190292847),
#   ("90Percentile" (1; #1), 6763.525486348508),
#   ("Energy" (1; #2), 6566.034776047452),
#   ("RootMeanSquared" (1; #13), 3786.6447458306925),
#   ("Range" (1; #11), 2668.345129467765),
#   ("Mean" (1; #7), 2521.327939366868),
#   ("Kurtosis" (1; #5), 2072.6286654039286),
#   ("Median" (1; #9), 2008.7963084308303),
#   ("MeanAbsoluteDeviation" (1; #8), 1684.303018625935),
#   ("Skewness" (1; #14), 1663.1967846625191),
#   ("Uniformity" (1; #16), 1385.0507309019313),
#   ("10Percentile" (1; #0), 1237.5107629576146),
#   ("RobustMeanAbsoluteDeviation" (1; #12), 1032.0545809001715),
#   ("Variance" (1; #17), 1003.8635021926075),
#   ("InterquartileRange" (1; #4), 971.4626321914852),
#   ("Entropy" (1; #3), 771.5450547924156)],
#  'NUM_NODES': [("Skewness" (1; #14), 343.0),
#   ("Median" (1; #9), 331.0),
#   ("90Percentile" (1; #1), 316.0),
#   ("Maximum" (1; #6), 312.0),
#   ("Minimum" (1; #10), 299.0),
#   ("Kurtosis" (1; #5), 250.0),
#   ("Uniformity" (1; #16), 243.0),
#   ("Range" (1; #11), 220.0),
#   ("Variance" (1; #17), 201.0),
#   ("10Percentile" (1; #0), 192.0),
#   ("RobustMeanAbsoluteDeviation" (1; #12), 172.0),
#   ("Mean" (1; #7), 171.0),
#   ("Entropy" (1; #3), 162.0),
#   ("InterquartileRange" (1; #4), 127.0),
#   ("MeanAbsoluteDeviation" (1; #8), 107.0),
#   ("TotalEnergy" (1; #15), 90.0),
#   ("RootMeanSquared" (1; #13), 78.0),
#   ("Energy" (1; #2), 72.0)]}

# %%
# Model self evaluation
model.make_inspector().evaluation()
# Out:
# Evaluation(num_examples=None, accuracy=0.8606536388397217, loss=0.6397517323493958, rmse=None, ndcg=None, aucs=None, auuc=None, qini=None)

# %%
logs = model.make_inspector().training_logs()

plt.figure(figsize=(12, 4))
plt.subplot(1, 2, 1)
plt.plot([log.num_trees for log in logs], [log.evaluation.accuracy for log in logs])
plt.xlabel("Number of trees")
plt.ylabel("Accuracy (out-of-bag)")
plt.subplot(1, 2, 2)
plt.plot([log.num_trees for log in logs], [log.evaluation.loss for log in logs])
plt.xlabel("Number of trees")
plt.ylabel("Logloss (out-of-bag)")
plt.show()

# %% [markdown]
# Calculate the score of our hold-out validation dataset

# %%
predictions = model.predict(val_ds)
y_true      = validation_data["label"]

from sklearn.metrics import roc_auc_score
ROC_AUC = roc_auc_score(y_true, predictions)
print("The ROC AUC score is %.5f" % ROC_AUC )
# Out:
#  1/12 [=>............................] - ETA: 0s
# 12/12 [==============================] - 0s 4ms/step
# The ROC AUC score is 0.93275

# %%
# Compute binary classification metrics with sklearn
import numpy as np
from sklearn.metrics import (
    accuracy_score,
    precision_score,
    recall_score,
    f1_score,
    roc_auc_score,
    average_precision_score,
    confusion_matrix,
    classification_report,
    matthews_corrcoef,
    log_loss,
    brier_score_loss,
)

# Get predictions (probabilities or class labels)
preds = model.predict(test_ds)
# If model outputs probabilities, convert to labels by threshold 0.5
if preds.ndim == 2:
    # For TFDF classification, preds may be class probabilities with shape (N, 2)
    if preds.shape[1] == 2:
        pos_probs = preds[:, 1]
    else:
        # If single-probability column (positive class)
        pos_probs = preds[:, -1]
    y_pred = (pos_probs >= 0.5).astype(int)
else:
    # Already class labels
    y_pred = preds.astype(int)
    pos_probs = None

# Ground truth labels (must be 0/1 integers)
y_true = test_data["label"].astype(int).to_numpy()

# Core metrics
metrics = {}
metrics["accuracy"] = accuracy_score(y_true, y_pred)
metrics["precision"] = precision_score(y_true, y_pred, zero_division=0)
metrics["recall"] = recall_score(y_true, y_pred, zero_division=0)
metrics["f1"] = f1_score(y_true, y_pred, zero_division=0)
metrics["mcc"] = matthews_corrcoef(y_true, y_pred)

# Probabilistic metrics (only if we have probabilities)
if pos_probs is not None:
    metrics["roc_auc"] = roc_auc_score(y_true, pos_probs)
    metrics["pr_auc"] = average_precision_score(y_true, pos_probs)
    metrics["log_loss"] = log_loss(y_true, pos_probs, labels=[0,1])
    metrics["brier_score"] = brier_score_loss(y_true, pos_probs)

# Confusion matrix and detailed report
cm = confusion_matrix(y_true, y_pred, labels=[0,1])
report = classification_report(y_true, y_pred, digits=4)

print("Sklearn binary metrics:")
for k, v in metrics.items():
    print(f"{k}: {v:.4f}")
print("\nConfusion matrix:\n", cm)
print("\nClassification report:\n", report)
# Out:
#  1/23 [>.............................] - ETA: 1s
# 12/23 [==============>...............] - ETA: 0s
# 23/23 [==============================] - 0s 5ms/step
# Sklearn binary metrics:
# accuracy: 0.9016
# precision: 0.4089
# recall: 0.8053
# f1: 0.5424
# mcc: 0.5295
# roc_auc: 0.9333
# pr_auc: 0.7199
# log_loss: 0.2701
# brier_score: 0.0778
#
# Confusion matrix:
#  [[18967  1895]
#  [  317  1311]]
#
# Classification report:
#                precision    recall  f1-score   support
#
#            0     0.9836    0.9092    0.9449     20862
#            1     0.4089    0.8053    0.5424      1628
#
#     accuracy                         0.9016     22490
#    macro avg     0.6962    0.8572    0.7437     22490
# weighted avg     0.9420    0.9016    0.9158     22490
