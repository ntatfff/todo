# %%
# Import packages and modules
import numpy  as np
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow_decision_forests as tfdf

from sklearn.model_selection import train_test_split
# Out:
# 2026-07-04 09:01:47.053898: I tensorflow/core/util/port.cc:113] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2026-07-04 09:01:47.095490: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2026-07-04 09:01:51.394794: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
# Check the version of TensorFlow Decision Forests
print("Found TensorFlow Decision Forests v" + tfdf.__version__)
# Out:
# Found TensorFlow Decision Forests v1.9.1

# %%
datasetPath = 'dataset/firstorder/kernel5-radius5/dataset.csv'

# %%
# Parameters
datasetPath = "dataset/glszm/kernel5-radius5/300.dataset.csv"

# %%
# train/validation/test = 70/10/20
dataset = pd.read_csv(datasetPath)

train_data, temp_data = train_test_split(dataset, test_size=0.3, random_state=42)
validation_data, test_data = train_test_split(temp_data, test_size=2/3, random_state=42)

# %%
from sklearn.utils.class_weight import compute_class_weight

# tinh class weight tren tap train
classes = np.array([0, 1])
weights = compute_class_weight(class_weight="balanced", classes=classes, y=train_data["label"])
class_weight = {0: weights[0], 1: weights[1]}

# gan sample_weight cho tung dong
train_data["sample_weight"] = train_data["label"].map(class_weight)
validation_data["sample_weight"] = validation_data["label"].map(class_weight)
test_data["sample_weight"] = test_data["label"].map(class_weight)

# Convert the dataset into a TensorFlow dataset.
train_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    train_data, label="label", weight="sample_weight"
)         
val_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    validation_data, label="label", weight="sample_weight"
)
test_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    test_data, label="label", weight="sample_weight"
)
# Out:
# 2026-07-04 09:02:03.845407: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:984] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2026-07-04 09:02:03.846813: W tensorflow/core/common_runtime/gpu/gpu_device.cc:2251] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...

# %%
import keras

# %%
# %%time

# Train a Gradient Boosted Trees model.
model = tfdf.keras.GradientBoostedTreesModel()

# Add evaluation metrics
model.compile(
    metrics=["accuracy"]
)
model.fit(x=train_ds)

# # Train a Gradient Boosted Trees model.
# model = tfdf.keras.GradientBoostedTreesModel(num_trees=1500)
# model.fit(train_ds)
# Out:
# Use /tmp/tmpixfofigl as temporary training directory
# Reading training dataset...
# [WARNING 26-07-04 09:02:04.0029 UTC gradient_boosted_trees.cc:1840] "goss_alpha" set but "sampling_method" not equal to "GOSS".
# [WARNING 26-07-04 09:02:04.0029 UTC gradient_boosted_trees.cc:1851] "goss_beta" set but "sampling_method" not equal to "GOSS".
# [WARNING 26-07-04 09:02:04.0029 UTC gradient_boosted_trees.cc:1865] "selective_gradient_boosting_ratio" set but "sampling_method" not equal to "SELGB".
# Training dataset read in 0:00:03.360874. Found 235478 examples.
# Training model...
# Model trained in 0:00:59.459214
# Compiling model...
# [INFO 26-07-04 09:03:06.8326 UTC kernel.cc:1233] Loading model from path /tmp/tmpixfofigl/model/ with prefix fff2f417fb6343c1
# [INFO 26-07-04 09:03:06.8468 UTC quick_scorer_extended.cc:911] The binary was compiled without AVX2 support, but your CPU supports it. Enable it for faster model inference.
# [INFO 26-07-04 09:03:06.8480 UTC abstract_model.cc:1362] Engine "GradientBoostedTreesQuickScorerExtended" built
# [INFO 26-07-04 09:03:06.8481 UTC kernel.cc:1061] Use fast generic engine
# Model compiled.
# CPU times: user 7min 19s, sys: 4.08 s, total: 7min 23s
# Wall time: 1min 5s

# %%
# Evaluate the model
evaluate = model.evaluate(val_ds, return_dict=True)
print()

for name, value in evaluate.items():
    print(f"{name}: {value:.4f}")
# Out:
# WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
#  1/34 [..............................] - ETA: 1:36 - loss: 0.0000e+00 - accuracy: 0.9110
# 12/34 [=========>....................] - ETA: 0s - loss: 0.0000e+00 - accuracy: 0.8892
# 24/34 [====================>.........] - ETA: 0s - loss: 0.0000e+00 - accuracy: 0.8880
# 34/34 [==============================] - 3s 4ms/step - loss: 0.0000e+00 - accuracy: 0.8886
# loss: 0.0000
# accuracy: 0.8886

# %%
# Model Summary
model.summary()
# Out:
# Model: "gradient_boosted_trees_model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
# =================================================================
# Total params: 1 (1.00 Byte)
# Trainable params: 0 (0.00 Byte)
# Non-trainable params: 1 (1.00 Byte)
# _________________________________________________________________
# Type: "GRADIENT_BOOSTED_TREES"
# Task: CLASSIFICATION
# Label: "__LABEL"
#
# Input Features (16):
# 	GrayLevelNonUniformity
# 	GrayLevelNonUniformityNormalized
# 	GrayLevelVariance
# 	HighGrayLevelZoneEmphasis
# 	LargeAreaEmphasis
# 	LargeAreaHighGrayLevelEmphasis
# 	LargeAreaLowGrayLevelEmphasis
# 	LowGrayLevelZoneEmphasis
# 	SizeZoneNonUniformity
# 	SizeZoneNonUniformityNormalized
# 	SmallAreaEmphasis
# 	SmallAreaHighGrayLevelEmphasis
# 	SmallAreaLowGrayLevelEmphasis
# 	ZoneEntropy
# 	ZonePercentage
# 	ZoneVariance
#
# Trained with weights
#
# Variable Importance: INV_MEAN_MIN_DEPTH:
#     1.   "LargeAreaHighGrayLevelEmphasis"  0.290466 ################
#     2.           "GrayLevelNonUniformity"  0.230435 #######
#     3.        "HighGrayLevelZoneEmphasis"  0.215996 #####
#     4.                     "ZoneVariance"  0.209005 ####
#     5.    "LargeAreaLowGrayLevelEmphasis"  0.205740 ####
#     6.                "GrayLevelVariance"  0.194338 ##
#     7.    "SmallAreaLowGrayLevelEmphasis"  0.192839 ##
#     8.         "LowGrayLevelZoneEmphasis"  0.192809 ##
#     9.   "SmallAreaHighGrayLevelEmphasis"  0.187010 #
#    10.                      "ZoneEntropy"  0.186551 #
#    11.                "SmallAreaEmphasis"  0.182532
#    12. "GrayLevelNonUniformityNormalized"  0.182116
#    13.  "SizeZoneNonUniformityNormalized"  0.178357
#    14.                "LargeAreaEmphasis"  0.177750
#    15.                   "ZonePercentage"  0.176064
#    16.            "SizeZoneNonUniformity"  0.175472
#
# Variable Importance: NUM_AS_ROOT:
#     1.   "LargeAreaHighGrayLevelEmphasis" 121.000000 ################
#     2.           "GrayLevelNonUniformity" 53.000000 ######
#     3.        "HighGrayLevelZoneEmphasis" 38.000000 ####
#     4.    "SmallAreaLowGrayLevelEmphasis" 18.000000 ##
#     5.         "LowGrayLevelZoneEmphasis" 16.000000 ##
#     6.                "GrayLevelVariance" 14.000000 #
#     7.    "LargeAreaLowGrayLevelEmphasis" 12.000000 #
#     8.                     "ZoneVariance"  9.000000 #
#     9.   "SmallAreaHighGrayLevelEmphasis"  5.000000
#    10.                      "ZoneEntropy"  4.000000
#    11.                "SmallAreaEmphasis"  3.000000
#    12.  "SizeZoneNonUniformityNormalized"  2.000000
#    13. "GrayLevelNonUniformityNormalized"  1.000000
#
# Variable Importance: NUM_NODES:
#     1.   "LargeAreaHighGrayLevelEmphasis" 901.000000 ################
#     2.    "LargeAreaLowGrayLevelEmphasis" 831.000000 ##############
#     3.        "HighGrayLevelZoneEmphasis" 803.000000 #############
#     4.                     "ZoneVariance" 684.000000 ###########
#     5.           "GrayLevelNonUniformity" 682.000000 ###########
#     6.         "LowGrayLevelZoneEmphasis" 539.000000 ########
#     7.    "SmallAreaLowGrayLevelEmphasis" 504.000000 #######
#     8.   "SmallAreaHighGrayLevelEmphasis" 485.000000 ######
#     9.                      "ZoneEntropy" 484.000000 ######
#    10.                "GrayLevelVariance" 475.000000 ######
#    11. "GrayLevelNonUniformityNormalized" 360.000000 ####
#    12.                "SmallAreaEmphasis" 295.000000 ##
#    13.  "SizeZoneNonUniformityNormalized" 278.000000 ##
#    14.                "LargeAreaEmphasis" 228.000000 #
#    15.            "SizeZoneNonUniformity" 196.000000
#    16.                   "ZonePercentage" 176.000000
#
# Variable Importance: SUM_SCORE:
#     1.        "HighGrayLevelZoneEmphasis" 92425.613601 ################
#     2.           "GrayLevelNonUniformity" 32020.699496 #####
#     3.    "LargeAreaLowGrayLevelEmphasis" 17682.983732 ##
#     4.   "LargeAreaHighGrayLevelEmphasis" 10704.646728 #
#     5.   "SmallAreaHighGrayLevelEmphasis" 9435.679445 #
#     6.  "SizeZoneNonUniformityNormalized" 8500.043010 #
#     7.    "SmallAreaLowGrayLevelEmphasis" 7733.844752 #
#     8.                     "ZoneVariance" 7255.830306 #
#     9.         "LowGrayLevelZoneEmphasis" 6567.079134 #
#    10.                      "ZoneEntropy" 4365.186419
#    11.                "GrayLevelVariance" 2844.572226
#    12. "GrayLevelNonUniformityNormalized" 1564.925704
#    13.                   "ZonePercentage" 1149.953151
#    14.                "SmallAreaEmphasis" 1083.655418
#    15.            "SizeZoneNonUniformity" 1026.478311
#    16.                "LargeAreaEmphasis" 807.620087
#
#
#
# Loss: BINOMIAL_LOG_LIKELIHOOD
# Validation loss value: 0.56308
# Number of trees per iteration: 1
# Node format: NOT_SET
# Number of trees: 296
# Total number of nodes: 16138
#
# Number of nodes by tree:
# Count: 296 Average: 54.5203 StdDev: 7.95254
# Min: 27 Max: 63 Ignored: 0
# ----------------------------------------------
# [ 27, 28)  1   0.34%   0.34%
# [ 28, 30)  1   0.34%   0.68%
# [ 30, 32)  3   1.01%   1.69%
# [ 32, 34)  2   0.68%   2.36%
# [ 34, 36)  2   0.68%   3.04%
# [ 36, 38)  3   1.01%   4.05%
# [ 38, 39)  0   0.00%   4.05%
# [ 39, 41)  3   1.01%   5.07%
# [ 41, 43)  6   2.03%   7.09% #
# [ 43, 45) 11   3.72%  10.81% ##
# [ 45, 47)  9   3.04%  13.85% #
# [ 47, 49) 26   8.78%  22.64% ####
# [ 49, 51) 16   5.41%  28.04% ###
# [ 51, 52) 18   6.08%  34.12% ###
# [ 52, 54) 17   5.74%  39.86% ###
# [ 54, 56) 19   6.42%  46.28% ###
# [ 56, 58) 36  12.16%  58.45% ######
# [ 58, 60) 25   8.45%  66.89% ####
# [ 60, 62) 35  11.82%  78.72% ######
# [ 62, 63] 63  21.28% 100.00% ##########
#
# Depth by leafs:
# Count: 8217 Average: 4.89656 StdDev: 0.415718
# Min: 1 Max: 5 Ignored: 0
# ----------------------------------------------
# [ 1, 2)    3   0.04%   0.04%
# [ 2, 3)   61   0.74%   0.78%
# [ 3, 4)  128   1.56%   2.34%
# [ 4, 5)  399   4.86%   7.19% #
# [ 5, 5] 7626  92.81% 100.00% ##########
#
# Number of training obs by leaf:
# Count: 8217 Average: 7630.62 StdDev: 26108.9
# Min: 5 Max: 209377 Ignored: 0
# ----------------------------------------------
# [      5,  10473) 7217  87.83%  87.83% ##########
# [  10473,  20942)  364   4.43%  92.26% #
# [  20942,  31410)  159   1.94%  94.19%
# [  31410,  41879)   89   1.08%  95.28%
# [  41879,  52348)   55   0.67%  95.95%
# [  52348,  62816)   37   0.45%  96.40%
# [  62816,  73285)   42   0.51%  96.91%
# [  73285,  83754)   25   0.30%  97.21%
# [  83754,  94222)   29   0.35%  97.57%
# [  94222, 104691)   16   0.19%  97.76%
# [ 104691, 115160)   17   0.21%  97.97%
# [ 115160, 125628)   14   0.17%  98.14%
# [ 125628, 136097)   12   0.15%  98.28%
# [ 136097, 146566)   22   0.27%  98.55%
# [ 146566, 157034)   23   0.28%  98.83%
# [ 157034, 167503)   26   0.32%  99.15%
# [ 167503, 177972)   17   0.21%  99.35%
# [ 177972, 188440)   19   0.23%  99.59%
# [ 188440, 198909)   16   0.19%  99.78%
# [ 198909, 209377]   18   0.22% 100.00%
#
# Attribute in nodes:
# 	901 : LargeAreaHighGrayLevelEmphasis [NUMERICAL]
# 	831 : LargeAreaLowGrayLevelEmphasis [NUMERICAL]
# 	803 : HighGrayLevelZoneEmphasis [NUMERICAL]
# 	684 : ZoneVariance [NUMERICAL]
# 	682 : GrayLevelNonUniformity [NUMERICAL]
# 	539 : LowGrayLevelZoneEmphasis [NUMERICAL]
# 	504 : SmallAreaLowGrayLevelEmphasis [NUMERICAL]
# 	485 : SmallAreaHighGrayLevelEmphasis [NUMERICAL]
# 	484 : ZoneEntropy [NUMERICAL]
# 	475 : GrayLevelVariance [NUMERICAL]
# 	360 : GrayLevelNonUniformityNormalized [NUMERICAL]
# 	295 : SmallAreaEmphasis [NUMERICAL]
# 	278 : SizeZoneNonUniformityNormalized [NUMERICAL]
# 	228 : LargeAreaEmphasis [NUMERICAL]
# 	196 : SizeZoneNonUniformity [NUMERICAL]
# 	176 : ZonePercentage [NUMERICAL]
#
# Attribute in nodes with depth <= 0:
# 	121 : LargeAreaHighGrayLevelEmphasis [NUMERICAL]
# 	53 : GrayLevelNonUniformity [NUMERICAL]
# 	38 : HighGrayLevelZoneEmphasis [NUMERICAL]
# 	18 : SmallAreaLowGrayLevelEmphasis [NUMERICAL]
# 	16 : LowGrayLevelZoneEmphasis [NUMERICAL]
# 	14 : GrayLevelVariance [NUMERICAL]
# 	12 : LargeAreaLowGrayLevelEmphasis [NUMERICAL]
# 	9 : ZoneVariance [NUMERICAL]
# 	5 : SmallAreaHighGrayLevelEmphasis [NUMERICAL]
# 	4 : ZoneEntropy [NUMERICAL]
# 	3 : SmallAreaEmphasis [NUMERICAL]
# 	2 : SizeZoneNonUniformityNormalized [NUMERICAL]
# 	1 : GrayLevelNonUniformityNormalized [NUMERICAL]
#
# Attribute in nodes with depth <= 1:
# 	229 : LargeAreaHighGrayLevelEmphasis [NUMERICAL]
# 	140 : GrayLevelNonUniformity [NUMERICAL]
# 	95 : ZoneVariance [NUMERICAL]
# 	76 : HighGrayLevelZoneEmphasis [NUMERICAL]
# 	62 : LargeAreaLowGrayLevelEmphasis [NUMERICAL]
# 	51 : GrayLevelVariance [NUMERICAL]
# 	43 : SmallAreaLowGrayLevelEmphasis [NUMERICAL]
# 	40 : LowGrayLevelZoneEmphasis [NUMERICAL]
# 	33 : SmallAreaEmphasis [NUMERICAL]
# 	31 : SmallAreaHighGrayLevelEmphasis [NUMERICAL]
# 	21 : GrayLevelNonUniformityNormalized [NUMERICAL]
# 	18 : ZoneEntropy [NUMERICAL]
# 	17 : LargeAreaEmphasis [NUMERICAL]
# 	16 : SizeZoneNonUniformityNormalized [NUMERICAL]
# 	8 : SizeZoneNonUniformity [NUMERICAL]
# 	5 : ZonePercentage [NUMERICAL]
#
# Attribute in nodes with depth <= 2:
# 	340 : LargeAreaHighGrayLevelEmphasis [NUMERICAL]
# 	216 : ZoneVariance [NUMERICAL]
# 	211 : GrayLevelNonUniformity [NUMERICAL]
# 	207 : HighGrayLevelZoneEmphasis [NUMERICAL]
# 	189 : LargeAreaLowGrayLevelEmphasis [NUMERICAL]
# 	123 : GrayLevelVariance [NUMERICAL]
# 	108 : SmallAreaLowGrayLevelEmphasis [NUMERICAL]
# 	99 : LowGrayLevelZoneEmphasis [NUMERICAL]
# 	94 : ZoneEntropy [NUMERICAL]
# 	92 : SmallAreaHighGrayLevelEmphasis [NUMERICAL]
# 	76 : SmallAreaEmphasis [NUMERICAL]
# 	75 : GrayLevelNonUniformityNormalized [NUMERICAL]
# 	50 : LargeAreaEmphasis [NUMERICAL]
# 	45 : ZonePercentage [NUMERICAL]
# 	44 : SizeZoneNonUniformityNormalized [NUMERICAL]
# 	33 : SizeZoneNonUniformity [NUMERICAL]
#
# Attribute in nodes with depth <= 3:
# 	529 : LargeAreaHighGrayLevelEmphasis [NUMERICAL]
# 	418 : LargeAreaLowGrayLevelEmphasis [NUMERICAL]
# 	416 : HighGrayLevelZoneEmphasis [NUMERICAL]
# 	386 : ZoneVariance [NUMERICAL]
# 	379 : GrayLevelNonUniformity [NUMERICAL]
# 	256 : GrayLevelVariance [NUMERICAL]
# 	251 : ZoneEntropy [NUMERICAL]
# 	246 : LowGrayLevelZoneEmphasis [NUMERICAL]
# 	235 : SmallAreaHighGrayLevelEmphasis [NUMERICAL]
# 	234 : SmallAreaLowGrayLevelEmphasis [NUMERICAL]
# 	173 : GrayLevelNonUniformityNormalized [NUMERICAL]
# 	153 : SmallAreaEmphasis [NUMERICAL]
# 	125 : SizeZoneNonUniformityNormalized [NUMERICAL]
# 	112 : LargeAreaEmphasis [NUMERICAL]
# 	109 : ZonePercentage [NUMERICAL]
# 	86 : SizeZoneNonUniformity [NUMERICAL]
#
# Attribute in nodes with depth <= 5:
# 	901 : LargeAreaHighGrayLevelEmphasis [NUMERICAL]
# 	831 : LargeAreaLowGrayLevelEmphasis [NUMERICAL]
# 	803 : HighGrayLevelZoneEmphasis [NUMERICAL]
# 	684 : ZoneVariance [NUMERICAL]
# 	682 : GrayLevelNonUniformity [NUMERICAL]
# 	539 : LowGrayLevelZoneEmphasis [NUMERICAL]
# 	504 : SmallAreaLowGrayLevelEmphasis [NUMERICAL]
# 	485 : SmallAreaHighGrayLevelEmphasis [NUMERICAL]
# 	484 : ZoneEntropy [NUMERICAL]
# 	475 : GrayLevelVariance [NUMERICAL]
# 	360 : GrayLevelNonUniformityNormalized [NUMERICAL]
# 	295 : SmallAreaEmphasis [NUMERICAL]
# 	278 : SizeZoneNonUniformityNormalized [NUMERICAL]
# 	228 : LargeAreaEmphasis [NUMERICAL]
# 	196 : SizeZoneNonUniformity [NUMERICAL]
# 	176 : ZonePercentage [NUMERICAL]
#
# Condition type in nodes:
# 	7921 : HigherCondition
# Condition type in nodes with depth <= 0:
# 	296 : HigherCondition
# Condition type in nodes with depth <= 1:
# 	885 : HigherCondition
# Condition type in nodes with depth <= 2:
# 	2002 : HigherCondition
# Condition type in nodes with depth <= 3:
# 	4108 : HigherCondition
# Condition type in nodes with depth <= 5:
# 	7921 : HigherCondition
#
# Training logs:
# Number of iteration to final model: 296
# 	Iter:1 train-loss:1.292666 valid-loss:1.291799  train-accuracy:0.829183 valid-accuracy:0.830338
# 	Iter:2 train-loss:1.212795 valid-loss:1.212407  train-accuracy:0.831914 valid-accuracy:0.831739
# 	Iter:3 train-loss:1.142447 valid-loss:1.142187  train-accuracy:0.838210 valid-accuracy:0.838320
# 	Iter:4 train-loss:1.082929 valid-loss:1.083594  train-accuracy:0.841109 valid-accuracy:0.837810
# 	Iter:5 train-loss:1.031402 valid-loss:1.032549  train-accuracy:0.844876 valid-accuracy:0.840279
# 	Iter:6 train-loss:0.986276 valid-loss:0.987116  train-accuracy:0.847035 valid-accuracy:0.842597
# 	Iter:16 train-loss:0.745304 valid-loss:0.746384  train-accuracy:0.862807 valid-accuracy:0.860472
# 	Iter:26 train-loss:0.658672 valid-loss:0.662785  train-accuracy:0.870260 valid-accuracy:0.867646
# 	Iter:36 train-loss:0.616012 valid-loss:0.625077  train-accuracy:0.875933 valid-accuracy:0.871748
# 	Iter:46 train-loss:0.593242 valid-loss:0.607478  train-accuracy:0.879484 valid-accuracy:0.877401
# 	Iter:56 train-loss:0.578880 valid-loss:0.597569  train-accuracy:0.882031 valid-accuracy:0.880198
# 	Iter:66 train-loss:0.566573 valid-loss:0.590444  train-accuracy:0.884352 valid-accuracy:0.881168
# 	Iter:76 train-loss:0.556496 valid-loss:0.586362  train-accuracy:0.886204 valid-accuracy:0.881665
# 	Iter:86 train-loss:0.548589 valid-loss:0.582793  train-accuracy:0.888008 valid-accuracy:0.881510
# 	Iter:96 train-loss:0.539020 valid-loss:0.579106  train-accuracy:0.890524 valid-accuracy:0.881289
# 	Iter:106 train-loss:0.531186 valid-loss:0.575935  train-accuracy:0.892359 valid-accuracy:0.881684
# 	Iter:116 train-loss:0.524539 valid-loss:0.573739  train-accuracy:0.893881 valid-accuracy:0.882079
# 	Iter:126 train-loss:0.519594 valid-loss:0.572360  train-accuracy:0.895178 valid-accuracy:0.883067
# 	Iter:136 train-loss:0.513798 valid-loss:0.571052  train-accuracy:0.896232 valid-accuracy:0.882844
# 	Iter:146 train-loss:0.509466 valid-loss:0.570465  train-accuracy:0.897293 valid-accuracy:0.882644
# 	Iter:156 train-loss:0.504596 valid-loss:0.569883  train-accuracy:0.898950 valid-accuracy:0.880492
# 	Iter:166 train-loss:0.499482 valid-loss:0.567845  train-accuracy:0.900407 valid-accuracy:0.879641
# 	Iter:176 train-loss:0.494546 valid-loss:0.566720  train-accuracy:0.901648 valid-accuracy:0.881045
# 	Iter:186 train-loss:0.490631 valid-loss:0.566145  train-accuracy:0.902609 valid-accuracy:0.880226
# 	Iter:196 train-loss:0.486454 valid-loss:0.565459  train-accuracy:0.903596 valid-accuracy:0.880554
# 	Iter:206 train-loss:0.482200 valid-loss:0.565684  train-accuracy:0.904297 valid-accuracy:0.881004
# 	Iter:216 train-loss:0.478288 valid-loss:0.565891  train-accuracy:0.905748 valid-accuracy:0.880904
# 	Iter:226 train-loss:0.474400 valid-loss:0.564842  train-accuracy:0.906739 valid-accuracy:0.881882
# 	Iter:236 train-loss:0.469731 valid-loss:0.564907  train-accuracy:0.907423 valid-accuracy:0.882297
# 	Iter:246 train-loss:0.466378 valid-loss:0.564990  train-accuracy:0.908449 valid-accuracy:0.881199
# 	Iter:256 train-loss:0.462493 valid-loss:0.565026  train-accuracy:0.909705 valid-accuracy:0.881581
# 	Iter:266 train-loss:0.458772 valid-loss:0.563862  train-accuracy:0.910901 valid-accuracy:0.880876
# 	Iter:276 train-loss:0.455411 valid-loss:0.563871  train-accuracy:0.911765 valid-accuracy:0.881718
# 	Iter:286 train-loss:0.451915 valid-loss:0.563847  train-accuracy:0.912474 valid-accuracy:0.881058
# 	Iter:296 train-loss:0.448144 valid-loss:0.563080  train-accuracy:0.913791 valid-accuracy:0.881811

# %%
# Model features
model.make_inspector().features()
# Out:
# ["GrayLevelNonUniformity" (1; #0),
#  "GrayLevelNonUniformityNormalized" (1; #1),
#  "GrayLevelVariance" (1; #2),
#  "HighGrayLevelZoneEmphasis" (1; #3),
#  "LargeAreaEmphasis" (1; #4),
#  "LargeAreaHighGrayLevelEmphasis" (1; #5),
#  "LargeAreaLowGrayLevelEmphasis" (1; #6),
#  "LowGrayLevelZoneEmphasis" (1; #7),
#  "SizeZoneNonUniformity" (1; #8),
#  "SizeZoneNonUniformityNormalized" (1; #9),
#  "SmallAreaEmphasis" (1; #10),
#  "SmallAreaHighGrayLevelEmphasis" (1; #11),
#  "SmallAreaLowGrayLevelEmphasis" (1; #12),
#  "ZoneEntropy" (1; #13),
#  "ZonePercentage" (1; #14),
#  "ZoneVariance" (1; #15)]

# %%
# Feature importance
model.make_inspector().variable_importances()
# Out:
# {'INV_MEAN_MIN_DEPTH': [("LargeAreaHighGrayLevelEmphasis" (1; #5),
#    0.29046601303623154),
#   ("GrayLevelNonUniformity" (1; #0), 0.23043486480943565),
#   ("HighGrayLevelZoneEmphasis" (1; #3), 0.21599645827482958),
#   ("ZoneVariance" (1; #15), 0.20900547076236148),
#   ("LargeAreaLowGrayLevelEmphasis" (1; #6), 0.2057399080936584),
#   ("GrayLevelVariance" (1; #2), 0.19433791774186115),
#   ("SmallAreaLowGrayLevelEmphasis" (1; #12), 0.19283870980031165),
#   ("LowGrayLevelZoneEmphasis" (1; #7), 0.19280937597272582),
#   ("SmallAreaHighGrayLevelEmphasis" (1; #11), 0.18701039283976695),
#   ("ZoneEntropy" (1; #13), 0.18655092667531012),
#   ("SmallAreaEmphasis" (1; #10), 0.18253168710231038),
#   ("GrayLevelNonUniformityNormalized" (1; #1), 0.1821162321128237),
#   ("SizeZoneNonUniformityNormalized" (1; #9), 0.1783573574789834),
#   ("LargeAreaEmphasis" (1; #4), 0.1777500013835396),
#   ("ZonePercentage" (1; #14), 0.1760643315965425),
#   ("SizeZoneNonUniformity" (1; #8), 0.1754716060259402)],
#  'NUM_AS_ROOT': [("LargeAreaHighGrayLevelEmphasis" (1; #5), 121.0),
#   ("GrayLevelNonUniformity" (1; #0), 53.0),
#   ("HighGrayLevelZoneEmphasis" (1; #3), 38.0),
#   ("SmallAreaLowGrayLevelEmphasis" (1; #12), 18.0),
#   ("LowGrayLevelZoneEmphasis" (1; #7), 16.0),
#   ("GrayLevelVariance" (1; #2), 14.0),
#   ("LargeAreaLowGrayLevelEmphasis" (1; #6), 12.0),
#   ("ZoneVariance" (1; #15), 9.0),
#   ("SmallAreaHighGrayLevelEmphasis" (1; #11), 5.0),
#   ("ZoneEntropy" (1; #13), 4.0),
#   ("SmallAreaEmphasis" (1; #10), 3.0),
#   ("SizeZoneNonUniformityNormalized" (1; #9), 2.0),
#   ("GrayLevelNonUniformityNormalized" (1; #1), 1.0)],
#  'SUM_SCORE': [("HighGrayLevelZoneEmphasis" (1; #3), 92425.61360071169),
#   ("GrayLevelNonUniformity" (1; #0), 32020.699495987476),
#   ("LargeAreaLowGrayLevelEmphasis" (1; #6), 17682.983732296576),
#   ("LargeAreaHighGrayLevelEmphasis" (1; #5), 10704.646728100373),
#   ("SmallAreaHighGrayLevelEmphasis" (1; #11), 9435.679445061696),
#   ("SizeZoneNonUniformityNormalized" (1; #9), 8500.043009536177),
#   ("SmallAreaLowGrayLevelEmphasis" (1; #12), 7733.844752221533),
#   ("ZoneVariance" (1; #15), 7255.830305651234),
#   ("LowGrayLevelZoneEmphasis" (1; #7), 6567.079134466615),
#   ("ZoneEntropy" (1; #13), 4365.186419155246),
#   ("GrayLevelVariance" (1; #2), 2844.572226072826),
#   ("GrayLevelNonUniformityNormalized" (1; #1), 1564.9257039842182),
#   ("ZonePercentage" (1; #14), 1149.9531510134034),
#   ("SmallAreaEmphasis" (1; #10), 1083.6554184571528),
#   ("SizeZoneNonUniformity" (1; #8), 1026.478310587414),
#   ("LargeAreaEmphasis" (1; #4), 807.6200871648366)],
#  'NUM_NODES': [("LargeAreaHighGrayLevelEmphasis" (1; #5), 901.0),
#   ("LargeAreaLowGrayLevelEmphasis" (1; #6), 831.0),
#   ("HighGrayLevelZoneEmphasis" (1; #3), 803.0),
#   ("ZoneVariance" (1; #15), 684.0),
#   ("GrayLevelNonUniformity" (1; #0), 682.0),
#   ("LowGrayLevelZoneEmphasis" (1; #7), 539.0),
#   ("SmallAreaLowGrayLevelEmphasis" (1; #12), 504.0),
#   ("SmallAreaHighGrayLevelEmphasis" (1; #11), 485.0),
#   ("ZoneEntropy" (1; #13), 484.0),
#   ("GrayLevelVariance" (1; #2), 475.0),
#   ("GrayLevelNonUniformityNormalized" (1; #1), 360.0),
#   ("SmallAreaEmphasis" (1; #10), 295.0),
#   ("SizeZoneNonUniformityNormalized" (1; #9), 278.0),
#   ("LargeAreaEmphasis" (1; #4), 228.0),
#   ("SizeZoneNonUniformity" (1; #8), 196.0),
#   ("ZonePercentage" (1; #14), 176.0)]}

# %%
# Model self evaluation
model.make_inspector().evaluation()
# Out:
# Evaluation(num_examples=None, accuracy=0.8818106651306152, loss=0.5630801916122437, rmse=None, ndcg=None, aucs=None, auuc=None, qini=None)

# %%
logs = model.make_inspector().training_logs()

plt.figure(figsize=(12, 4))
plt.subplot(1, 2, 1)
plt.plot([log.num_trees for log in logs], [log.evaluation.accuracy for log in logs])
plt.xlabel("Number of trees")
plt.ylabel("Accuracy (out-of-bag)")
plt.subplot(1, 2, 2)
plt.plot([log.num_trees for log in logs], [log.evaluation.loss for log in logs])
plt.xlabel("Number of trees")
plt.ylabel("Logloss (out-of-bag)")
plt.show()

# %% [markdown]
# Calculate the score of our hold-out validation dataset

# %%
predictions = model.predict(val_ds)
y_true      = validation_data["label"]

from sklearn.metrics import roc_auc_score
ROC_AUC = roc_auc_score(y_true, predictions)
print("The ROC AUC score is %.5f" % ROC_AUC )
# Out:
#  1/34 [..............................] - ETA: 2s
# 13/34 [==========>...................] - ETA: 0s
# 25/34 [=====================>........] - ETA: 0s
# 26/34 [=====================>........] - ETA: 0s
# 34/34 [==============================] - 1s 25ms/step
# The ROC AUC score is 0.94671

# %%
# Compute binary classification metrics with sklearn
import numpy as np
from sklearn.metrics import (
    accuracy_score,
    precision_score,
    recall_score,
    f1_score,
    roc_auc_score,
    average_precision_score,
    confusion_matrix,
    classification_report,
    matthews_corrcoef,
    log_loss,
    brier_score_loss,
)

# Get predictions (probabilities or class labels)
preds = model.predict(test_ds)
# If model outputs probabilities, convert to labels by threshold 0.5
if preds.ndim == 2:
    # For TFDF classification, preds may be class probabilities with shape (N, 2)
    if preds.shape[1] == 2:
        pos_probs = preds[:, 1]
    else:
        # If single-probability column (positive class)
        pos_probs = preds[:, -1]
    y_pred = (pos_probs >= 0.5).astype(int)
else:
    # Already class labels
    y_pred = preds.astype(int)
    pos_probs = None

# Ground truth labels (must be 0/1 integers)
y_true = test_data["label"].astype(int).to_numpy()

# Core metrics
metrics = {}
metrics["accuracy"] = accuracy_score(y_true, y_pred)
metrics["precision"] = precision_score(y_true, y_pred, zero_division=0)
metrics["recall"] = recall_score(y_true, y_pred, zero_division=0)
metrics["f1"] = f1_score(y_true, y_pred, zero_division=0)
metrics["mcc"] = matthews_corrcoef(y_true, y_pred)

# Probabilistic metrics (only if we have probabilities)
if pos_probs is not None:
    metrics["roc_auc"] = roc_auc_score(y_true, pos_probs)
    metrics["pr_auc"] = average_precision_score(y_true, pos_probs)
    metrics["log_loss"] = log_loss(y_true, pos_probs, labels=[0,1])
    metrics["brier_score"] = brier_score_loss(y_true, pos_probs)

# Confusion matrix and detailed report
cm = confusion_matrix(y_true, y_pred, labels=[0,1])
report = classification_report(y_true, y_pred, digits=4)

print("Sklearn binary metrics:")
for k, v in metrics.items():
    print(f"{k}: {v:.4f}")
print("\nConfusion matrix:\n", cm)
print("\nClassification report:\n", report)
# Out:
#  1/68 [..............................] - ETA: 4s
# 13/68 [====>.........................] - ETA: 0s
# 26/68 [==========>...................] - ETA: 0s
# 39/68 [================>.............] - ETA: 0s
# 48/68 [====================>.........] - ETA: 0s
# 60/68 [=========================>....] - ETA: 0s
# 68/68 [==============================] - 1s 18ms/step
# Sklearn binary metrics:
# accuracy: 0.8883
# precision: 0.3401
# recall: 0.8551
# f1: 0.4867
# mcc: 0.4956
# roc_auc: 0.9469
# pr_auc: 0.6553
# log_loss: 0.2582
# brier_score: 0.0797
#
# Confusion matrix:
#  [[56198  6914]
#  [  604  3564]]
#
# Classification report:
#                precision    recall  f1-score   support
#
#            0     0.9894    0.8904    0.9373     63112
#            1     0.3401    0.8551    0.4867      4168
#
#     accuracy                         0.8883     67280
#    macro avg     0.6648    0.8728    0.7120     67280
# weighted avg     0.9491    0.8883    0.9094     67280
