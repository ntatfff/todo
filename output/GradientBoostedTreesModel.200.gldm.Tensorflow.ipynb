# %%
# Import packages and modules
import numpy  as np
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow_decision_forests as tfdf

from sklearn.model_selection import train_test_split
# Out:
# 2026-07-04 08:33:58.164753: I tensorflow/core/util/port.cc:113] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2026-07-04 08:33:58.205014: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2026-07-04 08:34:02.608251: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
# Check the version of TensorFlow Decision Forests
print("Found TensorFlow Decision Forests v" + tfdf.__version__)
# Out:
# Found TensorFlow Decision Forests v1.9.1

# %%
datasetPath = 'dataset/firstorder/kernel5-radius5/dataset.csv'

# %%
# Parameters
datasetPath = "dataset/gldm/kernel5-radius5/200.dataset.csv"

# %%
# train/validation/test = 70/10/20
dataset = pd.read_csv(datasetPath)

train_data, temp_data = train_test_split(dataset, test_size=0.3, random_state=42)
validation_data, test_data = train_test_split(temp_data, test_size=2/3, random_state=42)

# %%
from sklearn.utils.class_weight import compute_class_weight

# tinh class weight tren tap train
classes = np.array([0, 1])
weights = compute_class_weight(class_weight="balanced", classes=classes, y=train_data["label"])
class_weight = {0: weights[0], 1: weights[1]}

# gan sample_weight cho tung dong
train_data["sample_weight"] = train_data["label"].map(class_weight)
validation_data["sample_weight"] = validation_data["label"].map(class_weight)
test_data["sample_weight"] = test_data["label"].map(class_weight)

# Convert the dataset into a TensorFlow dataset.
train_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    train_data, label="label", weight="sample_weight"
)         
val_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    validation_data, label="label", weight="sample_weight"
)
test_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    test_data, label="label", weight="sample_weight"
)
# Out:
# 2026-07-04 08:34:14.714847: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:984] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2026-07-04 08:34:14.715964: W tensorflow/core/common_runtime/gpu/gpu_device.cc:2251] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...

# %%
import keras

# %%
# %%time

# Train a Gradient Boosted Trees model.
model = tfdf.keras.GradientBoostedTreesModel()

# Add evaluation metrics
model.compile(
    metrics=["accuracy"]
)
model.fit(x=train_ds)

# # Train a Gradient Boosted Trees model.
# model = tfdf.keras.GradientBoostedTreesModel(num_trees=1500)
# model.fit(train_ds)
# Out:
# Use /tmp/tmpa6_esxie as temporary training directory
# Reading training dataset...
# [WARNING 26-07-04 08:34:14.8639 UTC gradient_boosted_trees.cc:1840] "goss_alpha" set but "sampling_method" not equal to "GOSS".
# [WARNING 26-07-04 08:34:14.8640 UTC gradient_boosted_trees.cc:1851] "goss_beta" set but "sampling_method" not equal to "GOSS".
# [WARNING 26-07-04 08:34:14.8640 UTC gradient_boosted_trees.cc:1865] "selective_gradient_boosting_ratio" set but "sampling_method" not equal to "SELGB".
# Training dataset read in 0:00:04.531601. Found 157612 examples.
# Training model...
# Model trained in 0:00:25.511151
# Compiling model...
# [INFO 26-07-04 08:34:44.9205 UTC kernel.cc:1233] Loading model from path /tmp/tmpa6_esxie/model/ with prefix 8e1a55c1c4a14a11
# [INFO 26-07-04 08:34:44.9301 UTC quick_scorer_extended.cc:911] The binary was compiled without AVX2 support, but your CPU supports it. Enable it for faster model inference.
# [INFO 26-07-04 08:34:44.9308 UTC abstract_model.cc:1362] Engine "GradientBoostedTreesQuickScorerExtended" built
# [INFO 26-07-04 08:34:44.9308 UTC kernel.cc:1061] Use fast generic engine
# Model compiled.
# CPU times: user 3min 7s, sys: 2.34 s, total: 3min 9s
# Wall time: 33.1 s

# %%
# Evaluate the model
evaluate = model.evaluate(val_ds, return_dict=True)
print()

for name, value in evaluate.items():
    print(f"{name}: {value:.4f}")
# Out:
# WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
#  1/23 [>.............................] - ETA: 1:40 - loss: 0.0000e+00 - accuracy: 0.9040
# 15/23 [==================>...........] - ETA: 0s - loss: 0.0000e+00 - accuracy: 0.8951
# 23/23 [==============================] - 5s 4ms/step - loss: 0.0000e+00 - accuracy: 0.8942
# loss: 0.0000
# accuracy: 0.8942

# %%
# Model Summary
model.summary()
# Out:
# Model: "gradient_boosted_trees_model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
# =================================================================
# Total params: 1 (1.00 Byte)
# Trainable params: 0 (0.00 Byte)
# Non-trainable params: 1 (1.00 Byte)
# _________________________________________________________________
# Type: "GRADIENT_BOOSTED_TREES"
# Task: CLASSIFICATION
# Label: "__LABEL"
#
# Input Features (14):
# 	DependenceEntropy
# 	DependenceNonUniformity
# 	DependenceNonUniformityNormalized
# 	DependenceVariance
# 	GrayLevelNonUniformity
# 	GrayLevelVariance
# 	HighGrayLevelEmphasis
# 	LargeDependenceEmphasis
# 	LargeDependenceHighGrayLevelEmphasis
# 	LargeDependenceLowGrayLevelEmphasis
# 	LowGrayLevelEmphasis
# 	SmallDependenceEmphasis
# 	SmallDependenceHighGrayLevelEmphasis
# 	SmallDependenceLowGrayLevelEmphasis
#
# Trained with weights
#
# Variable Importance: INV_MEAN_MIN_DEPTH:
#     1. "LargeDependenceHighGrayLevelEmphasis"  0.276370 ################
#     2.                    "DependenceEntropy"  0.221454 #######
#     3.  "SmallDependenceLowGrayLevelEmphasis"  0.217287 ######
#     4.               "GrayLevelNonUniformity"  0.209448 #####
#     5.                "HighGrayLevelEmphasis"  0.207697 #####
#     6.              "SmallDependenceEmphasis"  0.206882 #####
#     7. "SmallDependenceHighGrayLevelEmphasis"  0.202989 ####
#     8.                 "LowGrayLevelEmphasis"  0.197613 ###
#     9.                    "GrayLevelVariance"  0.196062 ###
#    10.  "LargeDependenceLowGrayLevelEmphasis"  0.185361 #
#    11.                   "DependenceVariance"  0.182499 #
#    12.              "LargeDependenceEmphasis"  0.180536 #
#    13.              "DependenceNonUniformity"  0.174243
#    14.    "DependenceNonUniformityNormalized"  0.173351
#
# Variable Importance: NUM_AS_ROOT:
#     1. "LargeDependenceHighGrayLevelEmphasis" 64.000000 ################
#     2.                    "DependenceEntropy" 21.000000 ####
#     3.  "SmallDependenceLowGrayLevelEmphasis" 21.000000 ####
#     4.               "GrayLevelNonUniformity" 19.000000 ####
#     5.                 "LowGrayLevelEmphasis" 17.000000 ###
#     6.                "HighGrayLevelEmphasis" 12.000000 ##
#     7.                    "GrayLevelVariance"  8.000000 #
#     8.              "SmallDependenceEmphasis"  8.000000 #
#     9.                   "DependenceVariance"  5.000000
#    10. "SmallDependenceHighGrayLevelEmphasis"  5.000000
#    11.              "LargeDependenceEmphasis"  4.000000
#    12.  "LargeDependenceLowGrayLevelEmphasis"  4.000000
#
# Variable Importance: NUM_NODES:
#     1. "LargeDependenceHighGrayLevelEmphasis" 644.000000 ################
#     2.                    "DependenceEntropy" 572.000000 #############
#     3.                "HighGrayLevelEmphasis" 521.000000 ############
#     4.  "SmallDependenceLowGrayLevelEmphasis" 491.000000 ###########
#     5. "SmallDependenceHighGrayLevelEmphasis" 461.000000 ##########
#     6.              "SmallDependenceEmphasis" 438.000000 ##########
#     7.                    "GrayLevelVariance" 421.000000 #########
#     8.               "GrayLevelNonUniformity" 406.000000 #########
#     9.                 "LowGrayLevelEmphasis" 295.000000 #####
#    10.  "LargeDependenceLowGrayLevelEmphasis" 265.000000 #####
#    11.                   "DependenceVariance" 258.000000 ####
#    12.              "LargeDependenceEmphasis" 156.000000 #
#    13.              "DependenceNonUniformity" 108.000000
#    14.    "DependenceNonUniformityNormalized" 91.000000
#
# Variable Importance: SUM_SCORE:
#     1.                 "LowGrayLevelEmphasis" 33107.714123 ################
#     2.                    "DependenceEntropy" 26076.401664 ############
#     3.                "HighGrayLevelEmphasis" 19225.565171 #########
#     4. "SmallDependenceHighGrayLevelEmphasis" 17719.298887 ########
#     5. "LargeDependenceHighGrayLevelEmphasis" 16988.564518 ########
#     6.  "SmallDependenceLowGrayLevelEmphasis" 9141.248398 ####
#     7.              "SmallDependenceEmphasis" 4426.683672 ##
#     8.               "GrayLevelNonUniformity" 4093.398536 #
#     9.                    "GrayLevelVariance" 2801.455783 #
#    10.                   "DependenceVariance" 2276.311728
#    11.  "LargeDependenceLowGrayLevelEmphasis" 1499.167737
#    12.              "LargeDependenceEmphasis" 757.605781
#    13.              "DependenceNonUniformity" 384.946864
#    14.    "DependenceNonUniformityNormalized" 319.618940
#
#
#
# Loss: BINOMIAL_LOG_LIKELIHOOD
# Validation loss value: 0.583424
# Number of trees per iteration: 1
# Node format: NOT_SET
# Number of trees: 188
# Total number of nodes: 10442
#
# Number of nodes by tree:
# Count: 188 Average: 55.5426 StdDev: 6.67986
# Min: 37 Max: 63 Ignored: 0
# ----------------------------------------------
# [ 37, 38)  1   0.53%   0.53%
# [ 38, 39)  0   0.00%   0.53%
# [ 39, 41)  1   0.53%   1.06%
# [ 41, 42)  7   3.72%   4.79% ##
# [ 42, 43)  0   0.00%   4.79%
# [ 43, 45)  6   3.19%   7.98% ##
# [ 45, 46)  7   3.72%  11.70% ##
# [ 46, 47)  0   0.00%  11.70%
# [ 47, 49) 10   5.32%  17.02% ###
# [ 49, 50)  9   4.79%  21.81% ##
# [ 50, 51)  0   0.00%  21.81%
# [ 51, 53) 12   6.38%  28.19% ###
# [ 53, 54)  8   4.26%  32.45% ##
# [ 54, 55)  0   0.00%  32.45%
# [ 55, 57) 22  11.70%  44.15% ######
# [ 57, 58) 26  13.83%  57.98% #######
# [ 58, 59)  0   0.00%  57.98%
# [ 59, 61) 15   7.98%  65.96% ####
# [ 61, 62) 25  13.30%  79.26% ######
# [ 62, 63] 39  20.74% 100.00% ##########
#
# Depth by leafs:
# Count: 5315 Average: 4.90254 StdDev: 0.384438
# Min: 2 Max: 5 Ignored: 0
# ----------------------------------------------
# [ 2, 3)   24   0.45%   0.45%
# [ 3, 4)   87   1.64%   2.09%
# [ 4, 5)  272   5.12%   7.21% #
# [ 5, 5] 4932  92.79% 100.00% ##########
#
# Number of training obs by leaf:
# Count: 5315 Average: 5018.87 StdDev: 15859.8
# Min: 5 Max: 134224 Ignored: 0
# ----------------------------------------------
# [      5,   6716) 4597  86.49%  86.49% ##########
# [   6716,  13427)  255   4.80%  91.29% #
# [  13427,  20138)  130   2.45%  93.73%
# [  20138,  26849)   71   1.34%  95.07%
# [  26849,  33560)   49   0.92%  95.99%
# [  33560,  40271)   32   0.60%  96.59%
# [  40271,  46982)   28   0.53%  97.12%
# [  46982,  53693)   15   0.28%  97.40%
# [  53693,  60404)   17   0.32%  97.72%
# [  60404,  67115)    9   0.17%  97.89%
# [  67115,  73826)    6   0.11%  98.01%
# [  73826,  80537)   11   0.21%  98.21%
# [  80537,  87248)   20   0.38%  98.59%
# [  87248,  93959)   20   0.38%  98.97%
# [  93959, 100670)   14   0.26%  99.23%
# [ 100670, 107381)    6   0.11%  99.34%
# [ 107381, 114092)   13   0.24%  99.59%
# [ 114092, 120803)   12   0.23%  99.81%
# [ 120803, 127514)    3   0.06%  99.87%
# [ 127514, 134224]    7   0.13% 100.00%
#
# Attribute in nodes:
# 	644 : LargeDependenceHighGrayLevelEmphasis [NUMERICAL]
# 	572 : DependenceEntropy [NUMERICAL]
# 	521 : HighGrayLevelEmphasis [NUMERICAL]
# 	491 : SmallDependenceLowGrayLevelEmphasis [NUMERICAL]
# 	461 : SmallDependenceHighGrayLevelEmphasis [NUMERICAL]
# 	438 : SmallDependenceEmphasis [NUMERICAL]
# 	421 : GrayLevelVariance [NUMERICAL]
# 	406 : GrayLevelNonUniformity [NUMERICAL]
# 	295 : LowGrayLevelEmphasis [NUMERICAL]
# 	265 : LargeDependenceLowGrayLevelEmphasis [NUMERICAL]
# 	258 : DependenceVariance [NUMERICAL]
# 	156 : LargeDependenceEmphasis [NUMERICAL]
# 	108 : DependenceNonUniformity [NUMERICAL]
# 	91 : DependenceNonUniformityNormalized [NUMERICAL]
#
# Attribute in nodes with depth <= 0:
# 	64 : LargeDependenceHighGrayLevelEmphasis [NUMERICAL]
# 	21 : SmallDependenceLowGrayLevelEmphasis [NUMERICAL]
# 	21 : DependenceEntropy [NUMERICAL]
# 	19 : GrayLevelNonUniformity [NUMERICAL]
# 	17 : LowGrayLevelEmphasis [NUMERICAL]
# 	12 : HighGrayLevelEmphasis [NUMERICAL]
# 	8 : SmallDependenceEmphasis [NUMERICAL]
# 	8 : GrayLevelVariance [NUMERICAL]
# 	5 : SmallDependenceHighGrayLevelEmphasis [NUMERICAL]
# 	5 : DependenceVariance [NUMERICAL]
# 	4 : LargeDependenceLowGrayLevelEmphasis [NUMERICAL]
# 	4 : LargeDependenceEmphasis [NUMERICAL]
#
# Attribute in nodes with depth <= 1:
# 	126 : LargeDependenceHighGrayLevelEmphasis [NUMERICAL]
# 	69 : DependenceEntropy [NUMERICAL]
# 	68 : SmallDependenceLowGrayLevelEmphasis [NUMERICAL]
# 	51 : SmallDependenceEmphasis [NUMERICAL]
# 	48 : GrayLevelNonUniformity [NUMERICAL]
# 	43 : SmallDependenceHighGrayLevelEmphasis [NUMERICAL]
# 	43 : HighGrayLevelEmphasis [NUMERICAL]
# 	35 : LowGrayLevelEmphasis [NUMERICAL]
# 	33 : GrayLevelVariance [NUMERICAL]
# 	20 : LargeDependenceLowGrayLevelEmphasis [NUMERICAL]
# 	14 : LargeDependenceEmphasis [NUMERICAL]
# 	11 : DependenceVariance [NUMERICAL]
# 	3 : DependenceNonUniformity [NUMERICAL]
#
# Attribute in nodes with depth <= 2:
# 	193 : LargeDependenceHighGrayLevelEmphasis [NUMERICAL]
# 	146 : SmallDependenceLowGrayLevelEmphasis [NUMERICAL]
# 	130 : SmallDependenceHighGrayLevelEmphasis [NUMERICAL]
# 	124 : SmallDependenceEmphasis [NUMERICAL]
# 	124 : HighGrayLevelEmphasis [NUMERICAL]
# 	118 : DependenceEntropy [NUMERICAL]
# 	112 : GrayLevelNonUniformity [NUMERICAL]
# 	90 : GrayLevelVariance [NUMERICAL]
# 	77 : LowGrayLevelEmphasis [NUMERICAL]
# 	54 : LargeDependenceLowGrayLevelEmphasis [NUMERICAL]
# 	49 : DependenceVariance [NUMERICAL]
# 	42 : LargeDependenceEmphasis [NUMERICAL]
# 	17 : DependenceNonUniformityNormalized [NUMERICAL]
# 	16 : DependenceNonUniformity [NUMERICAL]
#
# Attribute in nodes with depth <= 3:
# 	332 : LargeDependenceHighGrayLevelEmphasis [NUMERICAL]
# 	290 : DependenceEntropy [NUMERICAL]
# 	270 : HighGrayLevelEmphasis [NUMERICAL]
# 	261 : SmallDependenceLowGrayLevelEmphasis [NUMERICAL]
# 	255 : SmallDependenceEmphasis [NUMERICAL]
# 	249 : SmallDependenceHighGrayLevelEmphasis [NUMERICAL]
# 	221 : GrayLevelNonUniformity [NUMERICAL]
# 	213 : GrayLevelVariance [NUMERICAL]
# 	144 : LowGrayLevelEmphasis [NUMERICAL]
# 	133 : DependenceVariance [NUMERICAL]
# 	130 : LargeDependenceLowGrayLevelEmphasis [NUMERICAL]
# 	66 : LargeDependenceEmphasis [NUMERICAL]
# 	53 : DependenceNonUniformity [NUMERICAL]
# 	44 : DependenceNonUniformityNormalized [NUMERICAL]
#
# Attribute in nodes with depth <= 5:
# 	644 : LargeDependenceHighGrayLevelEmphasis [NUMERICAL]
# 	572 : DependenceEntropy [NUMERICAL]
# 	521 : HighGrayLevelEmphasis [NUMERICAL]
# 	491 : SmallDependenceLowGrayLevelEmphasis [NUMERICAL]
# 	461 : SmallDependenceHighGrayLevelEmphasis [NUMERICAL]
# 	438 : SmallDependenceEmphasis [NUMERICAL]
# 	421 : GrayLevelVariance [NUMERICAL]
# 	406 : GrayLevelNonUniformity [NUMERICAL]
# 	295 : LowGrayLevelEmphasis [NUMERICAL]
# 	265 : LargeDependenceLowGrayLevelEmphasis [NUMERICAL]
# 	258 : DependenceVariance [NUMERICAL]
# 	156 : LargeDependenceEmphasis [NUMERICAL]
# 	108 : DependenceNonUniformity [NUMERICAL]
# 	91 : DependenceNonUniformityNormalized [NUMERICAL]
#
# Condition type in nodes:
# 	5127 : HigherCondition
# Condition type in nodes with depth <= 0:
# 	188 : HigherCondition
# Condition type in nodes with depth <= 1:
# 	564 : HigherCondition
# Condition type in nodes with depth <= 2:
# 	1292 : HigherCondition
# Condition type in nodes with depth <= 3:
# 	2661 : HigherCondition
# Condition type in nodes with depth <= 5:
# 	5127 : HigherCondition
#
# Training logs:
# Number of iteration to final model: 188
# 	Iter:1 train-loss:1.285922 valid-loss:1.288572  train-accuracy:0.836957 valid-accuracy:0.827991
# 	Iter:2 train-loss:1.202727 valid-loss:1.207902  train-accuracy:0.839831 valid-accuracy:0.829905
# 	Iter:3 train-loss:1.133188 valid-loss:1.141254  train-accuracy:0.840084 valid-accuracy:0.828302
# 	Iter:4 train-loss:1.069470 valid-loss:1.079494  train-accuracy:0.847595 valid-accuracy:0.836270
# 	Iter:5 train-loss:1.018377 valid-loss:1.030454  train-accuracy:0.846185 valid-accuracy:0.836381
# 	Iter:6 train-loss:0.970652 valid-loss:0.985179  train-accuracy:0.850178 valid-accuracy:0.838388
# 	Iter:16 train-loss:0.712549 valid-loss:0.742971  train-accuracy:0.873246 valid-accuracy:0.853840
# 	Iter:26 train-loss:0.619835 valid-loss:0.663411  train-accuracy:0.880013 valid-accuracy:0.855796
# 	Iter:36 train-loss:0.578979 valid-loss:0.628756  train-accuracy:0.883182 valid-accuracy:0.860916
# 	Iter:46 train-loss:0.556268 valid-loss:0.615145  train-accuracy:0.885951 valid-accuracy:0.865811
# 	Iter:56 train-loss:0.540071 valid-loss:0.605886  train-accuracy:0.888267 valid-accuracy:0.863557
# 	Iter:66 train-loss:0.527413 valid-loss:0.600770  train-accuracy:0.890421 valid-accuracy:0.864552
# 	Iter:76 train-loss:0.516543 valid-loss:0.595972  train-accuracy:0.892924 valid-accuracy:0.865151
# 	Iter:86 train-loss:0.508296 valid-loss:0.593222  train-accuracy:0.895021 valid-accuracy:0.865339
# 	Iter:96 train-loss:0.501744 valid-loss:0.591441  train-accuracy:0.896626 valid-accuracy:0.864857
# 	Iter:106 train-loss:0.494950 valid-loss:0.590204  train-accuracy:0.898316 valid-accuracy:0.865268
# 	Iter:116 train-loss:0.487984 valid-loss:0.589031  train-accuracy:0.899894 valid-accuracy:0.866316
# 	Iter:126 train-loss:0.481406 valid-loss:0.588084  train-accuracy:0.901591 valid-accuracy:0.867071
# 	Iter:136 train-loss:0.474447 valid-loss:0.589228  train-accuracy:0.902796 valid-accuracy:0.867156
# 	Iter:146 train-loss:0.468124 valid-loss:0.587622  train-accuracy:0.904519 valid-accuracy:0.867945
# 	Iter:156 train-loss:0.462305 valid-loss:0.586835  train-accuracy:0.905666 valid-accuracy:0.868185
# 	Iter:166 train-loss:0.456263 valid-loss:0.586336  train-accuracy:0.907395 valid-accuracy:0.867239
# 	Iter:176 train-loss:0.450497 valid-loss:0.585302  train-accuracy:0.909338 valid-accuracy:0.870074
# 	Iter:186 train-loss:0.446379 valid-loss:0.583762  train-accuracy:0.910420 valid-accuracy:0.870589
# 	Iter:196 train-loss:0.441631 valid-loss:0.584109  train-accuracy:0.911093 valid-accuracy:0.868972
# 	Iter:206 train-loss:0.437342 valid-loss:0.584176  train-accuracy:0.912715 valid-accuracy:0.870347
# 	Iter:216 train-loss:0.432541 valid-loss:0.584905  train-accuracy:0.913982 valid-accuracy:0.869572

# %%
# Model features
model.make_inspector().features()
# Out:
# ["DependenceEntropy" (1; #0),
#  "DependenceNonUniformity" (1; #1),
#  "DependenceNonUniformityNormalized" (1; #2),
#  "DependenceVariance" (1; #3),
#  "GrayLevelNonUniformity" (1; #4),
#  "GrayLevelVariance" (1; #5),
#  "HighGrayLevelEmphasis" (1; #6),
#  "LargeDependenceEmphasis" (1; #7),
#  "LargeDependenceHighGrayLevelEmphasis" (1; #8),
#  "LargeDependenceLowGrayLevelEmphasis" (1; #9),
#  "LowGrayLevelEmphasis" (1; #10),
#  "SmallDependenceEmphasis" (1; #11),
#  "SmallDependenceHighGrayLevelEmphasis" (1; #12),
#  "SmallDependenceLowGrayLevelEmphasis" (1; #13)]

# %%
# Feature importance
model.make_inspector().variable_importances()
# Out:
# {'INV_MEAN_MIN_DEPTH': [("LargeDependenceHighGrayLevelEmphasis" (1; #8),
#    0.27636974267865133),
#   ("DependenceEntropy" (1; #0), 0.22145358521825972),
#   ("SmallDependenceLowGrayLevelEmphasis" (1; #13), 0.21728706660624092),
#   ("GrayLevelNonUniformity" (1; #4), 0.20944804547121887),
#   ("HighGrayLevelEmphasis" (1; #6), 0.2076966872635993),
#   ("SmallDependenceEmphasis" (1; #11), 0.20688249135821044),
#   ("SmallDependenceHighGrayLevelEmphasis" (1; #12), 0.2029886226853838),
#   ("LowGrayLevelEmphasis" (1; #10), 0.19761304022144174),
#   ("GrayLevelVariance" (1; #5), 0.19606196280189145),
#   ("LargeDependenceLowGrayLevelEmphasis" (1; #9), 0.18536125029360428),
#   ("DependenceVariance" (1; #3), 0.18249870432580945),
#   ("LargeDependenceEmphasis" (1; #7), 0.1805358088711742),
#   ("DependenceNonUniformity" (1; #1), 0.1742428045479448),
#   ("DependenceNonUniformityNormalized" (1; #2), 0.17335129031137647)],
#  'NUM_AS_ROOT': [("LargeDependenceHighGrayLevelEmphasis" (1; #8), 64.0),
#   ("DependenceEntropy" (1; #0), 21.0),
#   ("SmallDependenceLowGrayLevelEmphasis" (1; #13), 21.0),
#   ("GrayLevelNonUniformity" (1; #4), 19.0),
#   ("LowGrayLevelEmphasis" (1; #10), 17.0),
#   ("HighGrayLevelEmphasis" (1; #6), 12.0),
#   ("GrayLevelVariance" (1; #5), 8.0),
#   ("SmallDependenceEmphasis" (1; #11), 8.0),
#   ("DependenceVariance" (1; #3), 5.0),
#   ("SmallDependenceHighGrayLevelEmphasis" (1; #12), 5.0),
#   ("LargeDependenceEmphasis" (1; #7), 4.0),
#   ("LargeDependenceLowGrayLevelEmphasis" (1; #9), 4.0)],
#  'SUM_SCORE': [("LowGrayLevelEmphasis" (1; #10), 33107.71412344118),
#   ("DependenceEntropy" (1; #0), 26076.401664100715),
#   ("HighGrayLevelEmphasis" (1; #6), 19225.56517124633),
#   ("SmallDependenceHighGrayLevelEmphasis" (1; #12), 17719.298887466466),
#   ("LargeDependenceHighGrayLevelEmphasis" (1; #8), 16988.564517688756),
#   ("SmallDependenceLowGrayLevelEmphasis" (1; #13), 9141.24839840792),
#   ("SmallDependenceEmphasis" (1; #11), 4426.683672100953),
#   ("GrayLevelNonUniformity" (1; #4), 4093.398535771719),
#   ("GrayLevelVariance" (1; #5), 2801.455783037239),
#   ("DependenceVariance" (1; #3), 2276.3117280330976),
#   ("LargeDependenceLowGrayLevelEmphasis" (1; #9), 1499.1677367954976),
#   ("LargeDependenceEmphasis" (1; #7), 757.6057806378952),
#   ("DependenceNonUniformity" (1; #1), 384.94686409559347),
#   ("DependenceNonUniformityNormalized" (1; #2), 319.6189397558242)],
#  'NUM_NODES': [("LargeDependenceHighGrayLevelEmphasis" (1; #8), 644.0),
#   ("DependenceEntropy" (1; #0), 572.0),
#   ("HighGrayLevelEmphasis" (1; #6), 521.0),
#   ("SmallDependenceLowGrayLevelEmphasis" (1; #13), 491.0),
#   ("SmallDependenceHighGrayLevelEmphasis" (1; #12), 461.0),
#   ("SmallDependenceEmphasis" (1; #11), 438.0),
#   ("GrayLevelVariance" (1; #5), 421.0),
#   ("GrayLevelNonUniformity" (1; #4), 406.0),
#   ("LowGrayLevelEmphasis" (1; #10), 295.0),
#   ("LargeDependenceLowGrayLevelEmphasis" (1; #9), 265.0),
#   ("DependenceVariance" (1; #3), 258.0),
#   ("LargeDependenceEmphasis" (1; #7), 156.0),
#   ("DependenceNonUniformity" (1; #1), 108.0),
#   ("DependenceNonUniformityNormalized" (1; #2), 91.0)]}

# %%
# Model self evaluation
model.make_inspector().evaluation()
# Out:
# Evaluation(num_examples=None, accuracy=0.8708293437957764, loss=0.583423912525177, rmse=None, ndcg=None, aucs=None, auuc=None, qini=None)

# %%
logs = model.make_inspector().training_logs()

plt.figure(figsize=(12, 4))
plt.subplot(1, 2, 1)
plt.plot([log.num_trees for log in logs], [log.evaluation.accuracy for log in logs])
plt.xlabel("Number of trees")
plt.ylabel("Accuracy (out-of-bag)")
plt.subplot(1, 2, 2)
plt.plot([log.num_trees for log in logs], [log.evaluation.loss for log in logs])
plt.xlabel("Number of trees")
plt.ylabel("Logloss (out-of-bag)")
plt.show()

# %% [markdown]
# Calculate the score of our hold-out validation dataset

# %%
predictions = model.predict(val_ds)
y_true      = validation_data["label"]

from sklearn.metrics import roc_auc_score
ROC_AUC = roc_auc_score(y_true, predictions)
print("The ROC AUC score is %.5f" % ROC_AUC )
# Out:
#  1/23 [>.............................] - ETA: 1s
# 14/23 [=================>............] - ETA: 0s
# 23/23 [==============================] - 0s 4ms/step
# The ROC AUC score is 0.95199

# %%
# Compute binary classification metrics with sklearn
import numpy as np
from sklearn.metrics import (
    accuracy_score,
    precision_score,
    recall_score,
    f1_score,
    roc_auc_score,
    average_precision_score,
    confusion_matrix,
    classification_report,
    matthews_corrcoef,
    log_loss,
    brier_score_loss,
)

# Get predictions (probabilities or class labels)
preds = model.predict(test_ds)
# If model outputs probabilities, convert to labels by threshold 0.5
if preds.ndim == 2:
    # For TFDF classification, preds may be class probabilities with shape (N, 2)
    if preds.shape[1] == 2:
        pos_probs = preds[:, 1]
    else:
        # If single-probability column (positive class)
        pos_probs = preds[:, -1]
    y_pred = (pos_probs >= 0.5).astype(int)
else:
    # Already class labels
    y_pred = preds.astype(int)
    pos_probs = None

# Ground truth labels (must be 0/1 integers)
y_true = test_data["label"].astype(int).to_numpy()

# Core metrics
metrics = {}
metrics["accuracy"] = accuracy_score(y_true, y_pred)
metrics["precision"] = precision_score(y_true, y_pred, zero_division=0)
metrics["recall"] = recall_score(y_true, y_pred, zero_division=0)
metrics["f1"] = f1_score(y_true, y_pred, zero_division=0)
metrics["mcc"] = matthews_corrcoef(y_true, y_pred)

# Probabilistic metrics (only if we have probabilities)
if pos_probs is not None:
    metrics["roc_auc"] = roc_auc_score(y_true, pos_probs)
    metrics["pr_auc"] = average_precision_score(y_true, pos_probs)
    metrics["log_loss"] = log_loss(y_true, pos_probs, labels=[0,1])
    metrics["brier_score"] = brier_score_loss(y_true, pos_probs)

# Confusion matrix and detailed report
cm = confusion_matrix(y_true, y_pred, labels=[0,1])
report = classification_report(y_true, y_pred, digits=4)

print("Sklearn binary metrics:")
for k, v in metrics.items():
    print(f"{k}: {v:.4f}")
print("\nConfusion matrix:\n", cm)
print("\nClassification report:\n", report)
# Out:
#  1/46 [..............................] - ETA: 2s
# 14/46 [========>.....................] - ETA: 0s
# 27/46 [================>.............] - ETA: 0s
# 42/46 [==========================>...] - ETA: 0s
# 46/46 [==============================] - 0s 4ms/step
# Sklearn binary metrics:
# accuracy: 0.8959
# precision: 0.3738
# recall: 0.8607
# f1: 0.5212
# mcc: 0.5249
# roc_auc: 0.9514
# pr_auc: 0.7057
# log_loss: 0.2491
# brier_score: 0.0756
#
# Confusion matrix:
#  [[37794  4274]
#  [  413  2551]]
#
# Classification report:
#                precision    recall  f1-score   support
#
#            0     0.9892    0.8984    0.9416     42068
#            1     0.3738    0.8607    0.5212      2964
#
#     accuracy                         0.8959     45032
#    macro avg     0.6815    0.8795    0.7314     45032
# weighted avg     0.9487    0.8959    0.9139     45032
