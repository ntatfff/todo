# %%
# Import packages and modules
import numpy  as np
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow_decision_forests as tfdf

from sklearn.model_selection import train_test_split
# Out:
# 2026-07-04 08:40:38.322784: I tensorflow/core/util/port.cc:113] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2026-07-04 08:40:38.362925: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2026-07-04 08:40:42.754637: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
# Check the version of TensorFlow Decision Forests
print("Found TensorFlow Decision Forests v" + tfdf.__version__)
# Out:
# Found TensorFlow Decision Forests v1.9.1

# %%
datasetPath = 'dataset/firstorder/kernel5-radius5/dataset.csv'

# %%
# Parameters
datasetPath = "dataset/gldm/kernel5-radius5/100.dataset.csv"

# %%
# train/validation/test = 70/10/20
dataset = pd.read_csv(datasetPath)

train_data, temp_data = train_test_split(dataset, test_size=0.3, random_state=42)
validation_data, test_data = train_test_split(temp_data, test_size=2/3, random_state=42)

# %%
from sklearn.utils.class_weight import compute_class_weight

# tinh class weight tren tap train
classes = np.array([0, 1])
weights = compute_class_weight(class_weight="balanced", classes=classes, y=train_data["label"])
class_weight = {0: weights[0], 1: weights[1]}

# gan sample_weight cho tung dong
train_data["sample_weight"] = train_data["label"].map(class_weight)
validation_data["sample_weight"] = validation_data["label"].map(class_weight)
test_data["sample_weight"] = test_data["label"].map(class_weight)

# Convert the dataset into a TensorFlow dataset.
train_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    train_data, label="label", weight="sample_weight"
)         
val_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    validation_data, label="label", weight="sample_weight"
)
test_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    test_data, label="label", weight="sample_weight"
)
# Out:
# 2026-07-04 08:40:54.788220: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:984] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2026-07-04 08:40:54.790255: W tensorflow/core/common_runtime/gpu/gpu_device.cc:2251] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...

# %%
import keras

# %%
# %%time

# Train a Random Forest model.
model = tfdf.keras.RandomForestModel()

# Add evaluation metrics
model.compile(
    metrics=["accuracy"]
)
model.fit(x=train_ds)

# # Train a Gradient Boosted Trees model.
# model = tfdf.keras.GradientBoostedTreesModel(num_trees=1500)
# model.fit(train_ds)
# Out:
# Use /tmp/tmpwbf6m9hs as temporary training directory
# Reading training dataset...
# Training dataset read in 0:00:02.910972. Found 78790 examples.
# Training model...
# [INFO 26-07-04 08:41:04.6694 UTC kernel.cc:1233] Loading model from path /tmp/tmpwbf6m9hs/model/ with prefix 5a4a8edae56f47d8
# Model trained in 0:00:07.759435
# Compiling model...
# [INFO 26-07-04 08:41:05.4965 UTC decision_forest.cc:734] Model loaded with 300 root(s), 691364 node(s), and 14 input feature(s).
# [INFO 26-07-04 08:41:05.4965 UTC abstract_model.cc:1362] Engine "RandomForestOptPred" built
# [INFO 26-07-04 08:41:05.4965 UTC kernel.cc:1061] Use fast generic engine
# Model compiled.
# CPU times: user 1min 24s, sys: 928 ms, total: 1min 25s
# Wall time: 15.2 s

# %%
# Evaluate the model
evaluate = model.evaluate(val_ds, return_dict=True)
print()

for name, value in evaluate.items():
    print(f"{name}: {value:.4f}")
# Out:
# WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
#  1/12 [=>............................] - ETA: 31s - loss: 0.0000e+00 - accuracy: 0.9490
#  3/12 [======>.......................] - ETA: 0s - loss: 0.0000e+00 - accuracy: 0.9563
#  5/12 [===========>..................] - ETA: 0s - loss: 0.0000e+00 - accuracy: 0.9580
#  7/12 [================>.............] - ETA: 0s - loss: 0.0000e+00 - accuracy: 0.9600
# 10/12 [========================>.....] - ETA: 0s - loss: 0.0000e+00 - accuracy: 0.9586
# 12/12 [==============================] - 3s 24ms/step - loss: 0.0000e+00 - accuracy: 0.9582
# loss: 0.0000
# accuracy: 0.9582

# %%
# Model Summary
model.summary()
# Out:
# Model: "random_forest_model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
# =================================================================
# Total params: 1 (1.00 Byte)
# Trainable params: 0 (0.00 Byte)
# Non-trainable params: 1 (1.00 Byte)
# _________________________________________________________________
# Type: "RANDOM_FOREST"
# Task: CLASSIFICATION
# Label: "__LABEL"
#
# Input Features (14):
# 	DependenceEntropy
# 	DependenceNonUniformity
# 	DependenceNonUniformityNormalized
# 	DependenceVariance
# 	GrayLevelNonUniformity
# 	GrayLevelVariance
# 	HighGrayLevelEmphasis
# 	LargeDependenceEmphasis
# 	LargeDependenceHighGrayLevelEmphasis
# 	LargeDependenceLowGrayLevelEmphasis
# 	LowGrayLevelEmphasis
# 	SmallDependenceEmphasis
# 	SmallDependenceHighGrayLevelEmphasis
# 	SmallDependenceLowGrayLevelEmphasis
#
# Trained with weights
#
# Variable Importance: INV_MEAN_MIN_DEPTH:
#     1.                "HighGrayLevelEmphasis"  0.223990 ################
#     2. "LargeDependenceHighGrayLevelEmphasis"  0.196350 ############
#     3.                    "DependenceEntropy"  0.156107 #######
#     4.                 "LowGrayLevelEmphasis"  0.129855 ####
#     5.              "SmallDependenceEmphasis"  0.124388 ####
#     6.  "SmallDependenceLowGrayLevelEmphasis"  0.121248 ###
#     7. "SmallDependenceHighGrayLevelEmphasis"  0.119795 ###
#     8.               "GrayLevelNonUniformity"  0.110936 ##
#     9.  "LargeDependenceLowGrayLevelEmphasis"  0.102448 #
#    10.                    "GrayLevelVariance"  0.096858
#    11.    "DependenceNonUniformityNormalized"  0.091593
#    12.              "DependenceNonUniformity"  0.091292
#    13.              "LargeDependenceEmphasis"  0.091111
#    14.                   "DependenceVariance"  0.089210
#
# Variable Importance: NUM_AS_ROOT:
#     1.                "HighGrayLevelEmphasis" 109.000000 ################
#     2.                 "LowGrayLevelEmphasis" 62.000000 #########
#     3. "LargeDependenceHighGrayLevelEmphasis" 60.000000 ########
#     4. "SmallDependenceHighGrayLevelEmphasis" 36.000000 #####
#     5.  "LargeDependenceLowGrayLevelEmphasis" 15.000000 ##
#     6.  "SmallDependenceLowGrayLevelEmphasis" 11.000000 #
#     7.                    "DependenceEntropy"  5.000000
#     8.               "GrayLevelNonUniformity"  1.000000
#     9.              "LargeDependenceEmphasis"  1.000000
#
# Variable Importance: NUM_NODES:
#     1.                    "DependenceEntropy" 31066.000000 ################
#     2. "LargeDependenceHighGrayLevelEmphasis" 30522.000000 ###############
#     3.               "GrayLevelNonUniformity" 29319.000000 #############
#     4.                    "GrayLevelVariance" 27224.000000 ###########
#     5.              "SmallDependenceEmphasis" 26646.000000 ##########
#     6.  "SmallDependenceLowGrayLevelEmphasis" 26311.000000 ##########
#     7. "SmallDependenceHighGrayLevelEmphasis" 26104.000000 ##########
#     8.                "HighGrayLevelEmphasis" 25888.000000 #########
#     9.  "LargeDependenceLowGrayLevelEmphasis" 22789.000000 ######
#    10.                 "LowGrayLevelEmphasis" 22753.000000 ######
#    11.                   "DependenceVariance" 21498.000000 ####
#    12.              "LargeDependenceEmphasis" 19896.000000 ##
#    13.    "DependenceNonUniformityNormalized" 17774.000000
#    14.              "DependenceNonUniformity" 17742.000000
#
# Variable Importance: SUM_SCORE:
#     1.                
# [  7737,  8510)     37   0.01%  99.96%
# [  8510,  9283)     34   0.01%  99.97%
# [  9283, 10056)     20   0.01%  99.98%
# [ 10056, 10829)     24   0.01%  99.99%
# [ 10829, 11603)     19   0.01%  99.99%
# [ 11603, 12376)     10   0.00% 100.00%
# [ 12376, 13149)      7   0.00% 100.00%
# [ 13149, 13922)      4   0.00% 100.00%
# [ 13922, 14695)      2   0.00% 100.00%
# [ 14695, 15468]      2   0.00% 100.00%
#
# Attribute in nodes:
# 	31066 : DependenceEntropy [NUMERICAL]
# 	30522 : LargeDependenceHighGrayLevelEmphasis [NUMERICAL]
# 	29319 : GrayLevelNonUniformity [NUMERICAL]
# 	27224 : GrayLevelVariance [NUMERICAL]
# 	26646 : SmallDependenceEmphasis [NUMERICAL]
# 	26311 : SmallDependenceLowGrayLevelEmphasis [NUMERICAL]
# 	26104 : SmallDependenceHighGrayLevelEmphasis [NUMERICAL]
# 	25888 : HighGrayLevelEmphasis [NUMERICAL]
# 	22789 : LargeDependenceLowGrayLevelEmphasis [NUMERICAL]
# 	22753 : LowGrayLevelEmphasis [NUMERICAL]
# 	21498 : DependenceVariance [NUMERICAL]
# 	19896 : LargeDependenceEmphasis [NUMERICAL]
# 	17774 : DependenceNonUniformityNormalized [NUMERICAL]
# 	17742 : DependenceNonUniformity [NUMERICAL]
#
# Attribute in nodes with depth <= 0:
# 	109 : HighGrayLevelEmphasis [NUMERICAL]
# 	62 : LowGrayLevelEmphasis [NUMERICAL]
# 	60 : LargeDependenceHighGrayLevelEmphasis [NUMERICAL]
# 	36 : SmallDependenceHighGrayLevelEmphasis [NUMERICAL]
# 	15 : LargeDependenceLowGrayLevelEmphasis [NUMERICAL]
# 	11 : SmallDependenceLowGrayLevelEmphasis [NUMERICAL]
# 	5 : DependenceEntropy [NUMERICAL]
# 	1 : LargeDependenceEmphasis [NUMERICAL]
# 	1 : GrayLevelNonUniformity [NUMERICAL]
#
# Attribute in nodes with depth <= 1:
# 	264 : HighGrayLevelEmphasis [NUMERICAL]
# 	175 : LargeDependenceHighGrayLevelEmphasis [NUMERICAL]
# 	116 : LowGrayLevelEmphasis [NUMERICAL]
# 	91 : SmallDependenceHighGrayLevelEmphasis [NUMERICAL]
# 	66 : SmallDependenceLowGrayLevelEmphasis [NUMERICAL]
# 	47 : SmallDependenceEmphasis [NUMERICAL]
# 	42 : DependenceEntropy [NUMERICAL]
# 	37 : LargeDependenceLowGrayLevelEmphasis [NUMERICAL]
# 	25 : DependenceNonUniformityNormalized [NUMERICAL]
# 	21 : DependenceNonUniformity [NUMERICAL]
# 	9 : GrayLevelNonUniformity [NUMERICAL]
# 	5 : GrayLevelVariance [NUMERICAL]
# 	2 : LargeDependenceEmphasis [NUMERICAL]
#
# Attribute in nodes with depth <= 2:
# 	473 : HighGrayLevelEmphasis [NUMERICAL]
# 	383 : LargeDependenceHighGrayLevelEmphasis [NUMERICAL]
# 	228 : LowGrayLevelEmphasis [NUMERICAL]
# 	218 : DependenceEntropy [NUMERICAL]
# 	162 : SmallDependenceHighGrayLevelEmphasis [NUMERICAL]
# 	136 : SmallDependenceLowGrayLevelEmphasis [NUMERICAL]
# 	133 : SmallDependenceEmphasis [NUMERICAL]
# 	80 : LargeDependenceLowGrayLevelEmphasis [NUMERICAL]
# 	74 : GrayLevelNonUniformity [NUMERICAL]
# 	55 : DependenceNonUniformityNormalized [NUMERICAL]
# 	54 : DependenceNonUniformity [NUMERICAL]
# 	37 : DependenceVariance [NUMERICAL]
# 	36 : LargeDependenceEmphasis [NUMERICAL]
# 	31 : GrayLevelVariance [NUMERICAL]
#
# Attribute in nodes with depth <= 3:
# 	880 : HighGrayLevelEmphasis [NUMERICAL]
# 	772 : LargeDependenceHighGrayLevelEmphasis [NUMERICAL]
# 	624 : DependenceEntropy [NUMERICAL]
# 	407 : LowGrayLevelEmphasis [NUMERICAL]
# 	290 : SmallDependenceLowGrayLevelEmphasis [NUMERICAL]
# 	287 : GrayLevelNonUniformity [NUMERICAL]
# 	255 : SmallDependenceHighGrayLevelEmphasis [NUMERICAL]
# 	220 : SmallDependenceEmphasis [NUMERICAL]
# 	198 : LargeDependenceLowGrayLevelEmphasis [NUMERICAL]
# 	153 : GrayLevelVariance [NUMERICAL]
# 	112 : DependenceNonUniformity [NUMERICAL]
# 	109 : DependenceNonUniformityNormalized [NUMERICAL]
# 	99 : LargeDependenceEmphasis [NUMERICAL]
# 	91 : DependenceVariance [NUMERICAL]
#
# Attribute in nodes with depth <= 5:
# 	2604 : LargeDependenceHighGrayLevelEmphasis [NUMERICAL]
# 	2554 : DependenceEntropy [NUMERICAL]
# 	2163 : HighGrayLevelEmphasis [NUMERICAL]
# 	1470 : GrayLevelNonUniformity [NUMERICAL]
# 	1248 : SmallDependenceLowGrayLevelEmphasis [NUMERICAL]
# 	1224 : LowGrayLevelEmphasis [NUMERICAL]
# 	1123 : SmallDependenceEmphasis [NUMERICAL]
# 	1122 : GrayLevelVariance [NUMERICAL]
# 	1031 : SmallDependenceHighGrayLevelEmphasis [NUMERICAL]
# 	874 : LargeDependenceLowGrayLevelEmphasis [NUMERICAL]
# 	659 : DependenceVariance [NUMERICAL]
# 	586 : LargeDependenceEmphasis [NUMERICAL]
# 	541 : DependenceNonUniformity [NUMERICAL]
# 	539 : DependenceNonUniformityNormalized [NUMERICAL]
#
# Condition type in nodes:
# 	345532 : HigherCondition
# Condition type in nodes with depth <= 0:
# 	300 : HigherCondition
# Condition type in nodes with depth <= 1:
# 	900 : HigherCondition
# Condition type in nodes with depth <= 2:
# 	2100 : HigherCondition
# Condition type in nodes with depth <= 3:
# 	4497 : HigherCondition
# Condition type in nodes with depth <= 5:
# 	17738 : HigherCondition
# Node format: NOT_SET
#
# Training OOB:
# 	trees: 1, Out-of-bag evaluation: accuracy:0.827381 logloss:6.2218
# 	trees: 11, Out-of-bag evaluation: accuracy:0.836882 logloss:2.35336
# 	trees: 21, Out-of-bag evaluation: accuracy:0.851985 logloss:1.46212
# 	trees: 31, Out-of-bag evaluation: accuracy:0.856152 logloss:1.17644
# 	trees: 41, Out-of-bag evaluation: accuracy:0.858236 logloss:1.01643
# 	trees: 51, Out-of-bag evaluation: accuracy:0.85991 logloss:0.904408
# 	trees: 61, Out-of-bag evaluation: accuracy:0.861721 logloss:0.807544
# 	trees: 71, Out-of-bag evaluation: accuracy:0.86235 logloss:0.743125
# 	trees: 81, Out-of-bag evaluation: accuracy:0.861646 logloss:0.691627
# 	trees: 91, Out-of-bag evaluation: accuracy:0.86043 logloss:0.655941
# 	trees: 101, Out-of-bag evaluation: accuracy:0.860286 logloss:0.631532
# 	trees: 111, Out-of-bag evaluation: accuracy:0.860484 logloss:0.609553
# 	trees: 121, Out-of-bag evaluation: accuracy:0.859931 logloss:0.574044
# 	trees: 131, Out-of-bag evaluation: accuracy:0.86086 logloss:0.553294
# 	trees: 141, Out-of-bag evaluation: accuracy:0.86138 logloss:0.5294
# 	trees: 151, Out-of-bag evaluation: accuracy:0.861735 logloss:0.511844
# 	trees: 161, Out-of-bag evaluation: accuracy:0.861031 logloss:0.502248
# 	trees: 171, Out-of-bag evaluation: accuracy:0.860689 logloss:0.47613
# 	trees: 181, Out-of-bag evaluation: accuracy:0.8606 logloss:0.466528
# 	trees: 191, Out-of-bag evaluation: accuracy:0.86084 logloss:0.462503
# 	trees: 201, Out-of-bag evaluation: accuracy:0.861407 logloss:0.456298
# 	trees: 211, Out-of-bag evaluation: accuracy:0.86263 logloss:0.450215
# 	trees: 221, Out-of-bag evaluation: accuracy:0.861721 logloss:0.449543
# 	trees: 231, Out-of-bag evaluation: accuracy:0.861489 logloss:0.438146
# 	trees: 241, Out-of-bag evaluation: accuracy:0.86194 logloss:0.431831
# 	trees: 251, Out-of-bag evaluation: accuracy:0.861892 logloss:0.429044
# 	trees: 261, Out-of-bag evaluation: accuracy:0.862172 logloss:0.42584
# 	trees: 271, Out-of-bag evaluation: accuracy:0.862787 logloss:0.420264
# 	trees: 281, Out-of-bag evaluation: accuracy:0.862924 logloss:0.414295
# 	trees: 291, Out-of-bag evaluation: accuracy:0.863341 logloss:0.41104
# 	trees: 300, Out-of-bag evaluation: accuracy:0.862842 logloss:0.410959

# %%
# Model features
model.make_inspector().features()
# Out:
# ["DependenceEntropy" (1; #0),
#  "DependenceNonUniformity" (1; #1),
#  "DependenceNonUniformityNormalized" (1; #2),
#  "DependenceVariance" (1; #3),
#  "GrayLevelNonUniformity" (1; #4),
#  "GrayLevelVariance" (1; #5),
#  "HighGrayLevelEmphasis" (1; #6),
#  "LargeDependenceEmphasis" (1; #7),
#  "LargeDependenceHighGrayLevelEmphasis" (1; #8),
#  "LargeDependenceLowGrayLevelEmphasis" (1; #9),
#  "LowGrayLevelEmphasis" (1; #10),
#  "SmallDependenceEmphasis" (1; #11),
#  "SmallDependenceHighGrayLevelEmphasis" (1; #12),
#  "SmallDependenceLowGrayLevelEmphasis" (1; #13)]

# %%
# Feature importance
model.make_inspector().variable_importances()
# Out:
# {'INV_MEAN_MIN_DEPTH': [("HighGrayLevelEmphasis" (1; #6), 0.22399032169255464),
#   ("LargeDependenceHighGrayLevelEmphasis" (1; #8), 0.1963496353238279),
#   ("DependenceEntropy" (1; #0), 0.15610742066775565),
#   ("LowGrayLevelEmphasis" (1; #10), 0.1298554907343417),
#   ("SmallDependenceEmphasis" (1; #11), 0.12438750313606903),
#   ("SmallDependenceLowGrayLevelEmphasis" (1; #13), 0.12124781122821972),
#   ("SmallDependenceHighGrayLevelEmphasis" (1; #12), 0.11979498875544758),
#   ("GrayLevelNonUniformity" (1; #4), 0.11093623892174274),
#   ("LargeDependenceLowGrayLevelEmphasis" (1; #9), 0.10244800967279574),
#   ("GrayLevelVariance" (1; #5), 0.09685790194300335),
#   ("DependenceNonUniformityNormalized" (1; #2), 0.09159338319779153),
#   ("DependenceNonUniformity" (1; #1), 0.09129237249420658),
#   ("LargeDependenceEmphasis" (1; #7), 0.0911109939008196),
#   ("DependenceVariance" (1; #3), 0.08920993747810504)],
#  'NUM_AS_ROOT': [("HighGrayLevelEmphasis" (1; #6), 109.0),
#   ("LowGrayLevelEmphasis" (1; #10), 62.0),
#   ("LargeDependenceHighGrayLevelEmphasis" (1; #8), 60.0),
#   ("SmallDependenceHighGrayLevelEmphasis" (1; #12), 36.0),
#   ("LargeDependenceLowGrayLevelEmphasis" (1; #9), 15.0),
#   ("SmallDependenceLowGrayLevelEmphasis" (1; #13), 11.0),
#   ("DependenceEntropy" (1; #0), 5.0),
#   ("GrayLevelNonUniformity" (1; #4), 1.0),
#   ("LargeDependenceEmphasis" (1; #7), 1.0)],
#  'SUM_SCORE': [("HighGrayLevelEmphasis" (1; #6), 2670380.652344618),
#   ("LargeDependenceHighGrayLevelEmphasis" (1; #8), 1972612.922144184),
#   ("DependenceEntropy" (1; #0), 1602913.9797546857),
#   ("LowGrayLevelEmphasis" (1; #10), 1316466.7183713082),
#   ("SmallDependenceEmphasis" (1; #11), 1146240.7969534672),
#   ("SmallDependenceHighGrayLevelEmphasis" (1; #12), 1138756.612461866),
#   ("SmallDependenceLowGrayLevelEmphasis" (1; #13), 962177.0624598375),
#   ("GrayLevelNonUniformity" (1; #4), 863472.8691124584),
#   ("LargeDependenceLowGrayLevelEmphasis" (1; #9), 686487.0620685085),
#   ("GrayLevelVariance" (1; #5), 615318.7465101879),
#   ("LargeDependenceEmphasis" (1; #7), 440629.57301493495),
#   ("DependenceVariance" (1; #3), 417381.8015385668),
#   ("DependenceNonUniformity" (1; #1), 408720.7892447656),
#   ("DependenceNonUniformityNormalized" (1; #2), 407326.599670433)],
#  'NUM_NODES': [("DependenceEntropy" (1; #0), 31066.0),
#   ("LargeDependenceHighGrayLevelEmphasis" (1; #8), 30522.0),
#   ("GrayLevelNonUniformity" (1; #4), 29319.0),
#   ("GrayLevelVariance" (1; #5), 27224.0),
#   ("SmallDependenceEmphasis" (1; #11), 26646.0),
#   ("SmallDependenceLowGrayLevelEmphasis" (1; #13), 26311.0),
#   ("SmallDependenceHighGrayLevelEmphasis" (1; #12), 26104.0),
#   ("HighGrayLevelEmphasis" (1; #6), 25888.0),
#   ("LargeDependenceLowGrayLevelEmphasis" (1; #9), 22789.0),
#   ("LowGrayLevelEmphasis" (1; #10), 22753.0),
#   ("DependenceVariance" (1; #3), 21498.0),
#   ("LargeDependenceEmphasis" (1; #7), 19896.0),
#   ("DependenceNonUniformityNormalized" (1; #2), 17774.0),
#   ("DependenceNonUniformity" (1; #1), 17742.0)]}

# %%
# Model self evaluation
model.make_inspector().evaluation()
# Out:
# Evaluation(num_examples=78790, accuracy=0.862841998455659, loss=0.41095904312655546, rmse=None, ndcg=None, aucs=None, auuc=None, qini=None)

# %%
logs = model.make_inspector().training_logs()

plt.figure(figsize=(12, 4))
plt.subplot(1, 2, 1)
plt.plot([log.num_trees for log in logs], [log.evaluation.accuracy for log in logs])
plt.xlabel("Number of trees")
plt.ylabel("Accuracy (out-of-bag)")
plt.subplot(1, 2, 2)
plt.plot([log.num_trees for log in logs], [log.evaluation.loss for log in logs])
plt.xlabel("Number of trees")
plt.ylabel("Logloss (out-of-bag)")
plt.show()

# %% [markdown]
# Calculate the score of our hold-out validation dataset

# %%
predictions = model.predict(val_ds)
y_true      = validation_data["label"]

from sklearn.metrics import roc_auc_score
ROC_AUC = roc_auc_score(y_true, predictions)
print("The ROC AUC score is %.5f" % ROC_AUC )
# Out:
#  1/12 [=>............................] - ETA: 0s
#  3/12 [======>.......................] - ETA: 0s
#  5/12 [===========>..................] - ETA: 0s
#  7/12 [================>.............] - ETA: 0s
#  9/12 [=====================>........] - ETA: 0s
# 11/12 [==========================>...] - ETA: 0s
# 12/12 [==============================] - 0s 24ms/step
# The ROC AUC score is 0.95811

# %%
# Compute binary classification metrics with sklearn
import numpy as np
from sklearn.metrics import (
    accuracy_score,
    precision_score,
    recall_score,
    f1_score,
    roc_auc_score,
    average_precision_score,
    confusion_matrix,
    classification_report,
    matthews_corrcoef,
    log_loss,
    brier_score_loss,
)

# Get predictions (probabilities or class labels)
preds = model.predict(test_ds)
# If model outputs probabilities, convert to labels by threshold 0.5
if preds.ndim == 2:
    # For TFDF classification, preds may be class probabilities with shape (N, 2)
    if preds.shape[1] == 2:
        pos_probs = preds[:, 1]
    else:
        # If single-probability column (positive class)
        pos_probs = preds[:, -1]
    y_pred = (pos_probs >= 0.5).astype(int)
else:
    # Already class labels
    y_pred = preds.astype(int)
    pos_probs = None

# Ground truth labels (must be 0/1 integers)
y_true = test_data["label"].astype(int).to_numpy()

# Core metrics
metrics = {}
metrics["accuracy"] = accuracy_score(y_true, y_pred)
metrics["precision"] = precision_score(y_true, y_pred, zero_division=0)
metrics["recall"] = recall_score(y_true, y_pred, zero_division=0)
metrics["f1"] = f1_score(y_true, y_pred, zero_division=0)
metrics["mcc"] = matthews_corrcoef(y_true, y_pred)

# Probabilistic metrics (only if we have probabilities)
if pos_probs is not None:
    metrics["roc_auc"] = roc_auc_score(y_true, pos_probs)
    metrics["pr_auc"] = average_precision_score(y_true, pos_probs)
    metrics["log_loss"] = log_loss(y_true, pos_probs, labels=[0,1])
    metrics["brier_score"] = brier_score_loss(y_true, pos_probs)

# Confusion matrix and detailed report
cm = confusion_matrix(y_true, y_pred, labels=[0,1])
report = classification_report(y_true, y_pred, digits=4)

print("Sklearn binary metrics:")
for k, v in metrics.items():
    print(f"{k}: {v:.4f}")
print("\nConfusion matrix:\n", cm)
print("\nClassification report:\n", report)
# Out:
#  1/23 [>.............................] - ETA: 1s
#  3/23 [==>...........................] - ETA: 0s
#  6/23 [======>.......................] - ETA: 0s
#  9/23 [==========>...................] - ETA: 0s
# 11/23 [=============>................] - ETA: 0s
# 13/23 [===============>..............] - ETA: 0s
# 16/23 [===================>..........] - ETA: 0s
# 19/23 [=======================>......] - ETA: 0s
# 22/23 [===========================>..] - ETA: 0s
# 23/23 [==============================] - 1s 25ms/step
# Sklearn binary metrics:
# accuracy: 0.9582
# precision: 0.6974
# recall: 0.7651
# f1: 0.7297
# mcc: 0.7080
# roc_auc: 0.9620
# pr_auc: 0.8069
# log_loss: 0.1262
# brier_score: 0.0346
#
# Confusion matrix:
#  [[20301   551]
#  [  390  1270]]
#
# Classification report:
#                precision    recall  f1-score   support
#
#            0     0.9812    0.9736    0.9773     20852
#            1     0.6974    0.7651    0.7297      1660
#
#     accuracy                         0.9582     22512
#    macro avg     0.8393    0.8693    0.8535     22512
# weighted avg     0.9602    0.9582    0.9591     22512
