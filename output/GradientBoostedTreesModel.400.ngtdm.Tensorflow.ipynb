# %%
# Import packages and modules
import numpy  as np
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow_decision_forests as tfdf

from sklearn.model_selection import train_test_split
# Out:
# 2026-07-04 09:16:15.103231: I tensorflow/core/util/port.cc:113] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2026-07-04 09:16:15.142183: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2026-07-04 09:16:19.394273: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
# Check the version of TensorFlow Decision Forests
print("Found TensorFlow Decision Forests v" + tfdf.__version__)
# Out:
# Found TensorFlow Decision Forests v1.9.1

# %%
datasetPath = 'dataset/firstorder/kernel5-radius5/dataset.csv'

# %%
# Parameters
datasetPath = "dataset/ngtdm/kernel5-radius5/400.dataset.csv"

# %%
# train/validation/test = 70/10/20
dataset = pd.read_csv(datasetPath)

train_data, temp_data = train_test_split(dataset, test_size=0.3, random_state=42)
validation_data, test_data = train_test_split(temp_data, test_size=2/3, random_state=42)

# %%
from sklearn.utils.class_weight import compute_class_weight

# tinh class weight tren tap train
classes = np.array([0, 1])
weights = compute_class_weight(class_weight="balanced", classes=classes, y=train_data["label"])
class_weight = {0: weights[0], 1: weights[1]}

# gan sample_weight cho tung dong
train_data["sample_weight"] = train_data["label"].map(class_weight)
validation_data["sample_weight"] = validation_data["label"].map(class_weight)
test_data["sample_weight"] = test_data["label"].map(class_weight)

# Convert the dataset into a TensorFlow dataset.
train_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    train_data, label="label", weight="sample_weight"
)         
val_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    validation_data, label="label", weight="sample_weight"
)
test_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    test_data, label="label", weight="sample_weight"
)
# Out:
# 2026-07-04 09:16:33.293966: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:984] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2026-07-04 09:16:33.294876: W tensorflow/core/common_runtime/gpu/gpu_device.cc:2251] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...

# %%
import keras

# %%
# %%time

# Train a Gradient Boosted Trees model.
model = tfdf.keras.GradientBoostedTreesModel()

# Add evaluation metrics
model.compile(
    metrics=["accuracy"]
)
model.fit(x=train_ds)

# # Train a Gradient Boosted Trees model.
# model = tfdf.keras.GradientBoostedTreesModel(num_trees=1500)
# model.fit(train_ds)
# Out:
# Use /tmp/tmpgmu9rbbx as temporary training directory
# Reading training dataset...
# [WARNING 26-07-04 09:16:33.4242 UTC gradient_boosted_trees.cc:1840] "goss_alpha" set but "sampling_method" not equal to "GOSS".
# [WARNING 26-07-04 09:16:33.4242 UTC gradient_boosted_trees.cc:1851] "goss_beta" set but "sampling_method" not equal to "GOSS".
# [WARNING 26-07-04 09:16:33.4242 UTC gradient_boosted_trees.cc:1865] "selective_gradient_boosting_ratio" set but "sampling_method" not equal to "SELGB".
# Training dataset read in 0:00:02.897977. Found 315417 examples.
# Training model...
# Model trained in 0:00:42.058842
# Compiling model...
# [INFO 26-07-04 09:17:18.3912 UTC kernel.cc:1233] Loading model from path /tmp/tmpgmu9rbbx/model/ with prefix 8463a43f444a4472
# [INFO 26-07-04 09:17:18.4045 UTC quick_scorer_extended.cc:911] The binary was compiled without AVX2 support, but your CPU supports it. Enable it for faster model inference.
# [INFO 26-07-04 09:17:18.4059 UTC abstract_model.cc:1362] Engine "GradientBoostedTreesQuickScorerExtended" built
# [INFO 26-07-04 09:17:18.4060 UTC kernel.cc:1061] Use fast generic engine
# Model compiled.
# CPU times: user 2min 51s, sys: 1.75 s, total: 2min 53s
# Wall time: 47.9 s

# %%
# Evaluate the model
evaluate = model.evaluate(val_ds, return_dict=True)
print()

for name, value in evaluate.items():
    print(f"{name}: {value:.4f}")
# Out:
# WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
#  1/46 [..............................] - ETA: 2:11 - loss: 0.0000e+00 - accuracy: 0.8860
# 17/46 [==========>...................] - ETA: 0s - loss: 0.0000e+00 - accuracy: 0.8696
# 33/46 [====================>.........] - ETA: 0s - loss: 0.0000e+00 - accuracy: 0.8675
# 46/46 [==============================] - 3s 3ms/step - loss: 0.0000e+00 - accuracy: 0.8670
# loss: 0.0000
# accuracy: 0.8670

# %%
# Model Summary
model.summary()
# Out:
# Model: "gradient_boosted_trees_model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
# =================================================================
# Total params: 1 (1.00 Byte)
# Trainable params: 0 (0.00 Byte)
# Non-trainable params: 1 (1.00 Byte)
# _________________________________________________________________
# Type: "GRADIENT_BOOSTED_TREES"
# Task: CLASSIFICATION
# Label: "__LABEL"
#
# Input Features (5):
# 	Busyness
# 	Coarseness
# 	Complexity
# 	Contrast
# 	Strength
#
# Trained with weights
#
# Variable Importance: INV_MEAN_MIN_DEPTH:
#     1.   "Busyness"  0.325280 ################
#     2. "Complexity"  0.294892 ###########
#     3. "Coarseness"  0.266708 #######
#     4.   "Contrast"  0.262684 ######
#     5.   "Strength"  0.215747
#
# Variable Importance: NUM_AS_ROOT:
#     1. "Coarseness" 78.000000 ################
#     2.   "Busyness" 77.000000 ###############
#     3.   "Contrast" 61.000000 ############
#     4. "Complexity" 52.000000 ##########
#     5.   "Strength"  1.000000
#
# Variable Importance: NUM_NODES:
#     1.   "Busyness" 2004.000000 ################
#     2. "Complexity" 1427.000000 #####
#     3. "Coarseness" 1302.000000 ###
#     4.   "Contrast" 1300.000000 ###
#     5.   "Strength" 1102.000000
#
# Variable Importance: SUM_SCORE:
#     1. "Coarseness" 135944.567380 ################
#     2.   "Busyness" 63245.801730 ######
#     3. "Complexity" 25771.980225 ##
#     4.   "Contrast" 11475.703105
#     5.   "Strength" 9721.540559
#
#
#
# Loss: BINOMIAL_LOG_LIKELIHOOD
# Validation loss value: 0.645401
# Number of trees per iteration: 1
# Node format: NOT_SET
# Number of trees: 269
# Total number of nodes: 14539
#
# Number of nodes by tree:
# Count: 269 Average: 54.0483 StdDev: 7.72876
# Min: 33 Max: 63 Ignored: 0
# ----------------------------------------------
# [ 33, 34)  1   0.37%   0.37%
# [ 34, 36)  0   0.00%   0.37%
# [ 36, 37)  0   0.00%   0.37%
# [ 37, 39)  4   1.49%   1.86% #
# [ 39, 40)  8   2.97%   4.83% #
# [ 40, 42) 12   4.46%   9.29% ##
# [ 42, 43)  0   0.00%   9.29%
# [ 43, 45) 12   4.46%  13.75% ##
# [ 45, 46) 11   4.09%  17.84% ##
# [ 46, 48) 20   7.43%  25.28% ####
# [ 48, 50) 20   7.43%  32.71% ####
# [ 50, 51)  0   0.00%  32.71%
# [ 51, 53) 14   5.20%  37.92% ##
# [ 53, 54) 12   4.46%  42.38% ##
# [ 54, 56) 26   9.67%  52.04% #####
# [ 56, 57)  0   0.00%  52.04%
# [ 57, 59) 24   8.92%  60.97% ####
# [ 59, 60) 22   8.18%  69.14% ####
# [ 60, 62) 26   9.67%  78.81% #####
# [ 62, 63] 57  21.19% 100.00% ##########
#
# Depth by leafs:
# Count: 7404 Average: 4.88547 StdDev: 0.429352
# Min: 2 Max: 5 Ignored: 0
# ----------------------------------------------
# [ 2, 3)   49   0.66%   0.66%
# [ 3, 4)  160   2.16%   2.82%
# [ 4, 5)  381   5.15%   7.97% #
# [ 5, 5] 6814  92.03% 100.00% ##########
#
# Number of training obs by leaf:
# Count: 7404 Average: 10309.9 StdDev: 36985.9
# Min: 5 Max: 283175 Ignored: 0
# ----------------------------------------------
# [      5,  14163) 6571  88.75%  88.75% ##########
# [  14163,  28322)  277   3.74%  92.49%
# [  28322,  42480)  138   1.86%  94.35%
# [  42480,  56639)   78   1.05%  95.41%
# [  56639,  70797)   55   0.74%  96.15%
# [  70797,  84956)   31   0.42%  96.57%
# [  84956,  99114)   23   0.31%  96.88%
# [  99114, 113273)   19   0.26%  97.14%
# [ 113273, 127431)   12   0.16%  97.30%
# [ 127431, 141590)   17   0.23%  97.53%
# [ 141590, 155749)   11   0.15%  97.68%
# [ 155749, 169907)   17   0.23%  97.91%
# [ 169907, 184066)   20   0.27%  98.18%
# [ 184066, 198224)   13   0.18%  98.35%
# [ 198224, 212383)   23   0.31%  98.66%
# [ 212383, 226541)   14   0.19%  98.85%
# [ 226541, 240700)   26   0.35%  99.20%
# [ 240700, 254858)   15   0.20%  99.41%
# [ 254858, 269017)    8   0.11%  99.51%
# [ 269017, 283175]   36   0.49% 100.00%
#
# Attribute in nodes:
# 	2004 : Busyness [NUMERICAL]
# 	1427 : Complexity [NUMERICAL]
# 	1302 : Coarseness [NUMERICAL]
# 	1300 : Contrast [NUMERICAL]
# 	1102 : Strength [NUMERICAL]
#
# Attribute in nodes with depth <= 0:
# 	78 : Coarseness [NUMERICAL]
# 	77 : Busyness [NUMERICAL]
# 	61 : Contrast [NUMERICAL]
# 	52 : Complexity [NUMERICAL]
# 	1 : Strength [NUMERICAL]
#
# Attribute in nodes with depth <= 1:
# 	218 : Complexity [NUMERICAL]
# 	177 : Coarseness [NUMERICAL]
# 	171 : Contrast [NUMERICAL]
# 	170 : Busyness [NUMERICAL]
# 	71 : Strength [NUMERICAL]
#
# Attribute in nodes with depth <= 2:
# 	512 : Busyness [NUMERICAL]
# 	417 : Complexity [NUMERICAL]
# 	361 : Contrast [NUMERICAL]
# 	332 : Coarseness [NUMERICAL]
# 	212 : Strength [NUMERICAL]
#
# Attribute in nodes with depth <= 3:
# 	1007 : Busyness [NUMERICAL]
# 	777 : Complexity [NUMERICAL]
# 	705 : Contrast [NUMERICAL]
# 	693 : Coarseness [NUMERICAL]
# 	546 : Strength [NUMERICAL]
#
# Attribute in nodes with depth <= 5:
# 	2004 : Busyness [NUMERICAL]
# 	1427 : Complexity [NUMERICAL]
# 	1302 : Coarseness [NUMERICAL]
# 	1300 : Contrast [NUMERICAL]
# 	1102 : Strength [NUMERICAL]
#
# Condition type in nodes:
# 	7135 : HigherCondition
# Condition type in nodes with depth <= 0:
# 	269 : HigherCondition
# Condition type in nodes with depth <= 1:
# 	807 : HigherCondition
# Condition type in nodes with depth <= 2:
# 	1834 : HigherCondition
# Condition type in nodes with depth <= 3:
# 	3728 : HigherCondition
# Condition type in nodes with depth <= 5:
# 	7135 : HigherCondition
#
# Training logs:
# Number of iteration to final model: 269
# 	Iter:1 train-loss:1.291718 valid-loss:1.292736  train-accuracy:0.817306 valid-accuracy:0.819420
# 	Iter:2 train-loss:1.213455 valid-loss:1.215688  train-accuracy:0.824641 valid-accuracy:0.825775
# 	Iter:3 train-loss:1.147748 valid-loss:1.150864  train-accuracy:0.824031 valid-accuracy:0.825431
# 	Iter:4 train-loss:1.093341 valid-loss:1.096324  train-accuracy:0.826809 valid-accuracy:0.828717
# 	Iter:5 train-loss:1.046154 valid-loss:1.050704  train-accuracy:0.829946 valid-accuracy:0.829580
# 	Iter:6 train-loss:1.006300 valid-loss:1.011785  train-accuracy:0.836747 valid-accuracy:0.836570
# 	Iter:16 train-loss:0.797928 valid-loss:0.809586  train-accuracy:0.844512 valid-accuracy:0.840098
# 	Iter:26 train-loss:0.727365 valid-loss:0.742557  train-accuracy:0.849074 valid-accuracy:0.845761
# 	Iter:36 train-loss:0.689106 valid-loss:0.705735  train-accuracy:0.854012 valid-accuracy:0.848394
# 	Iter:46 train-loss:0.670248 valid-loss:0.690976  train-accuracy:0.857428 valid-accuracy:0.851573
# 	Iter:56 train-loss:0.658157 valid-loss:0.682647  train-accuracy:0.859157 valid-accuracy:0.850815
# 	Iter:66 train-loss:0.646916 valid-loss:0.675848  train-accuracy:0.861275 valid-accuracy:0.852514
# 	Iter:76 train-loss:0.639077 valid-loss:0.670486  train-accuracy:0.863084 valid-accuracy:0.853816
# 	Iter:86 train-loss:0.632286 valid-loss:0.667359  train-accuracy:0.864429 valid-accuracy:0.854988
# 	Iter:96 train-loss:0.625512 valid-loss:0.663444  train-accuracy:0.866110 valid-accuracy:0.856683
# 	Iter:106 train-loss:0.619517 valid-loss:0.660549  train-accuracy:0.867477 valid-accuracy:0.856805
# 	Iter:116 train-loss:0.614333 valid-loss:0.657018  train-accuracy:0.868542 valid-accuracy:0.857602
# 	Iter:126 train-loss:0.608863 valid-loss:0.654841  train-accuracy:0.869966 valid-accuracy:0.858080
# 	Iter:136 train-loss:0.604847 valid-loss:0.653342  train-accuracy:0.870870 valid-accuracy:0.858928
# 	Iter:146 train-loss:0.601039 valid-loss:0.651786  train-accuracy:0.871707 valid-accuracy:0.858543
# 	Iter:156 train-loss:0.597468 valid-loss:0.650314  train-accuracy:0.872512 valid-accuracy:0.858716
# 	Iter:166 train-loss:0.594906 valid-loss:0.649755  train-accuracy:0.873136 valid-accuracy:0.858446
# 	Iter:176 train-loss:0.591444 valid-loss:0.649406  train-accuracy:0.874205 valid-accuracy:0.857670
# 	Iter:186 train-loss:0.588563 valid-loss:0.648776  train-accuracy:0.875241 valid-accuracy:0.857892
# 	Iter:196 train-loss:0.585674 valid-loss:0.647605  train-accuracy:0.875960 valid-accuracy:0.857761
# 	Iter:206 train-loss:0.582878 valid-loss:0.647348  train-accuracy:0.876342 valid-accuracy:0.858268
# 	Iter:216 train-loss:0.580376 valid-loss:0.647335  train-accuracy:0.876861 valid-accuracy:0.858100
# 	Iter:226 train-loss:0.577308 valid-loss:0.646650  train-accuracy:0.877668 valid-accuracy:0.857561
# 	Iter:236 train-loss:0.574776 valid-loss:0.645961  train-accuracy:0.878503 valid-accuracy:0.858629
# 	Iter:246 train-loss:0.572114 valid-loss:0.646161  train-accuracy:0.879175 valid-accuracy:0.856874
# 	Iter:256 train-loss:0.570137 valid-loss:0.645762  train-accuracy:0.879759 valid-accuracy:0.857264
# 	Iter:266 train-loss:0.567310 valid-loss:0.645772  train-accuracy:0.880421 valid-accuracy:0.857334
# 	Iter:276 train-loss:0.565051 valid-loss:0.646123  train-accuracy:0.880992 valid-accuracy:0.857895
# 	Iter:286 train-loss:0.562857 valid-loss:0.645685  train-accuracy:0.881728 valid-accuracy:0.858285
# 	Iter:296 train-loss:0.561280 valid-loss:0.645999  train-accuracy:0.882286 valid-accuracy:0.858117

# %%
# Model features
model.make_inspector().features()
# Out:
# ["Busyness" (1; #0),
#  "Coarseness" (1; #1),
#  "Complexity" (1; #2),
#  "Contrast" (1; #3),
#  "Strength" (1; #4)]

# %%
# Feature importance
model.make_inspector().variable_importances()
# Out:
# {'INV_MEAN_MIN_DEPTH': [("Busyness" (1; #0), 0.3252795085462836),
#   ("Complexity" (1; #2), 0.29489187865358674),
#   ("Coarseness" (1; #1), 0.2667075918386937),
#   ("Contrast" (1; #3), 0.26268362724388483),
#   ("Strength" (1; #4), 0.21574691423380668)],
#  'NUM_AS_ROOT': [("Coarseness" (1; #1), 78.0),
#   ("Busyness" (1; #0), 77.0),
#   ("Contrast" (1; #3), 61.0),
#   ("Complexity" (1; #2), 52.0),
#   ("Strength" (1; #4), 1.0)],
#  'SUM_SCORE': [("Coarseness" (1; #1), 135944.5673796865),
#   ("Busyness" (1; #0), 63245.80172994349),
#   ("Complexity" (1; #2), 25771.98022477841),
#   ("Contrast" (1; #3), 11475.703104862832),
#   ("Strength" (1; #4), 9721.540559063174)],
#  'NUM_NODES': [("Busyness" (1; #0), 2004.0),
#   ("Complexity" (1; #2), 1427.0),
#   ("Coarseness" (1; #1), 1302.0),
#   ("Contrast" (1; #3), 1300.0),
#   ("Strength" (1; #4), 1102.0)]}

# %%
# Model self evaluation
model.make_inspector().evaluation()
# Out:
# Evaluation(num_examples=None, accuracy=0.8577073216438293, loss=0.6454011797904968, rmse=None, ndcg=None, aucs=None, auuc=None, qini=None)

# %%
logs = model.make_inspector().training_logs()

plt.figure(figsize=(12, 4))
plt.subplot(1, 2, 1)
plt.plot([log.num_trees for log in logs], [log.evaluation.accuracy for log in logs])
plt.xlabel("Number of trees")
plt.ylabel("Accuracy (out-of-bag)")
plt.subplot(1, 2, 2)
plt.plot([log.num_trees for log in logs], [log.evaluation.loss for log in logs])
plt.xlabel("Number of trees")
plt.ylabel("Logloss (out-of-bag)")
plt.show()

# %% [markdown]
# Calculate the score of our hold-out validation dataset

# %%
predictions = model.predict(val_ds)
y_true      = validation_data["label"]

from sklearn.metrics import roc_auc_score
ROC_AUC = roc_auc_score(y_true, predictions)
print("The ROC AUC score is %.5f" % ROC_AUC )
# Out:
#  1/46 [..............................] - ETA: 2s
# 16/46 [=========>....................] - ETA: 0s
# 33/46 [====================>.........] - ETA: 0s
# 46/46 [==============================] - 0s 3ms/step
# The ROC AUC score is 0.93306

# %%
# Compute binary classification metrics with sklearn
import numpy as np
from sklearn.metrics import (
    accuracy_score,
    precision_score,
    recall_score,
    f1_score,
    roc_auc_score,
    average_precision_score,
    confusion_matrix,
    classification_report,
    matthews_corrcoef,
    log_loss,
    brier_score_loss,
)

# Get predictions (probabilities or class labels)
preds = model.predict(test_ds)
# If model outputs probabilities, convert to labels by threshold 0.5
if preds.ndim == 2:
    # For TFDF classification, preds may be class probabilities with shape (N, 2)
    if preds.shape[1] == 2:
        pos_probs = preds[:, 1]
    else:
        # If single-probability column (positive class)
        pos_probs = preds[:, -1]
    y_pred = (pos_probs >= 0.5).astype(int)
else:
    # Already class labels
    y_pred = preds.astype(int)
    pos_probs = None

# Ground truth labels (must be 0/1 integers)
y_true = test_data["label"].astype(int).to_numpy()

# Core metrics
metrics = {}
metrics["accuracy"] = accuracy_score(y_true, y_pred)
metrics["precision"] = precision_score(y_true, y_pred, zero_division=0)
metrics["recall"] = recall_score(y_true, y_pred, zero_division=0)
metrics["f1"] = f1_score(y_true, y_pred, zero_division=0)
metrics["mcc"] = matthews_corrcoef(y_true, y_pred)

# Probabilistic metrics (only if we have probabilities)
if pos_probs is not None:
    metrics["roc_auc"] = roc_auc_score(y_true, pos_probs)
    metrics["pr_auc"] = average_precision_score(y_true, pos_probs)
    metrics["log_loss"] = log_loss(y_true, pos_probs, labels=[0,1])
    metrics["brier_score"] = brier_score_loss(y_true, pos_probs)

# Confusion matrix and detailed report
cm = confusion_matrix(y_true, y_pred, labels=[0,1])
report = classification_report(y_true, y_pred, digits=4)

print("Sklearn binary metrics:")
for k, v in metrics.items():
    print(f"{k}: {v:.4f}")
print("\nConfusion matrix:\n", cm)
print("\nClassification report:\n", report)
# Out:
#  1/91 [..............................] - ETA: 5s
# 17/91 [====>.........................] - ETA: 0s
# 32/91 [=========>....................] - ETA: 0s
# 46/91 [==============>...............] - ETA: 0s
# 62/91 [===================>..........] - ETA: 0s
# 77/91 [========================>.....] - ETA: 0s
# 91/91 [==============================] - 0s 3ms/step
# Sklearn binary metrics:
# accuracy: 0.8688
# precision: 0.3070
# recall: 0.8434
# f1: 0.4502
# mcc: 0.4589
# roc_auc: 0.9337
# pr_auc: 0.6234
# log_loss: 0.3060
# brier_score: 0.0952
#
# Confusion matrix:
#  [[73458 10923]
#  [  899  4840]]
#
# Classification report:
#                precision    recall  f1-score   support
#
#            0     0.9879    0.8706    0.9255     84381
#            1     0.3070    0.8434    0.4502      5739
#
#     accuracy                         0.8688     90120
#    macro avg     0.6475    0.8570    0.6879     90120
# weighted avg     0.9446    0.8688    0.8953     90120
