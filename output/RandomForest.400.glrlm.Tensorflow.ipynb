# %%
# Import packages and modules
import numpy  as np
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow_decision_forests as tfdf

from sklearn.model_selection import train_test_split
# Out:
# 2026-07-04 08:56:53.485704: I tensorflow/core/util/port.cc:113] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2026-07-04 08:56:53.530449: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2026-07-04 08:56:59.568092: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
# Check the version of TensorFlow Decision Forests
print("Found TensorFlow Decision Forests v" + tfdf.__version__)
# Out:
# Found TensorFlow Decision Forests v1.9.1

# %%
datasetPath = 'dataset/firstorder/kernel5-radius5/dataset.csv'

# %%
# Parameters
datasetPath = "dataset/glrlm/kernel5-radius5/400.dataset.csv"

# %%
# train/validation/test = 70/10/20
dataset = pd.read_csv(datasetPath)

train_data, temp_data = train_test_split(dataset, test_size=0.3, random_state=42)
validation_data, test_data = train_test_split(temp_data, test_size=2/3, random_state=42)

# %%
from sklearn.utils.class_weight import compute_class_weight

# tinh class weight tren tap train
classes = np.array([0, 1])
weights = compute_class_weight(class_weight="balanced", classes=classes, y=train_data["label"])
class_weight = {0: weights[0], 1: weights[1]}

# gan sample_weight cho tung dong
train_data["sample_weight"] = train_data["label"].map(class_weight)
validation_data["sample_weight"] = validation_data["label"].map(class_weight)
test_data["sample_weight"] = test_data["label"].map(class_weight)

# Convert the dataset into a TensorFlow dataset.
train_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    train_data, label="label", weight="sample_weight"
)         
val_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    validation_data, label="label", weight="sample_weight"
)
test_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    test_data, label="label", weight="sample_weight"
)
# Out:
# 2026-07-04 08:57:12.054883: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:984] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2026-07-04 08:57:12.056515: W tensorflow/core/common_runtime/gpu/gpu_device.cc:2251] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...

# %%
import keras

# %%
# %%time

# Train a Random Forest model.
model = tfdf.keras.RandomForestModel()

# Add evaluation metrics
model.compile(
    metrics=["accuracy"]
)
model.fit(x=train_ds)

# # Train a Gradient Boosted Trees model.
# model = tfdf.keras.GradientBoostedTreesModel(num_trees=1500)
# model.fit(train_ds)
# Out:
# Use /tmp/tmpa0wqoc9u as temporary training directory
# Reading training dataset...
# Training dataset read in 0:00:03.715004. Found 315452 examples.
# Training model...
# [INFO 26-07-04 08:57:51.2139 UTC kernel.cc:1233] Loading model from path /tmp/tmpa0wqoc9u/model/ with prefix a9786d5f729f447a
# [INFO 26-07-04 08:57:53.1560 UTC decision_forest.cc:734] Model loaded with 300 root(s), 1657998 node(s), and 16 input feature(s).
# [INFO 26-07-04 08:57:53.1560 UTC abstract_model.cc:1362] Engine "RandomForestOptPred" built
# [INFO 26-07-04 08:57:53.1560 UTC kernel.cc:1061] Use fast generic engine
# Model trained in 0:00:37.463903
# Compiling model...
# Model compiled.
# CPU times: user 6min 50s, sys: 2.58 s, total: 6min 52s
# Wall time: 44.5 s

# %%
# Evaluate the model
evaluate = model.evaluate(val_ds, return_dict=True)
print()

for name, value in evaluate.items():
    print(f"{name}: {value:.4f}")
# Out:
# WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
#  1/46 [..............................] - ETA: 3:31 - loss: 0.0000e+00 - accuracy: 0.9170
#  3/46 [>.............................] - ETA: 1s - loss: 0.0000e+00 - accuracy: 0.9087
#  5/46 [==>...........................] - ETA: 1s - loss: 0.0000e+00 - accuracy: 0.9088
#  7/46 [===>..........................] - ETA: 1s - loss: 0.0000e+00 - accuracy: 0.9120
#  9/46 [====>.........................] - ETA: 1s - loss: 0.0000e+00 - accuracy: 0.9097
# 11/46 [======>.......................] - ETA: 1s - loss: 0.0000e+00 - accuracy: 0.9099
# 13/46 [=======>......................] - ETA: 1s - loss: 0.0000e+00 - accuracy: 0.9118
# 15/46 [========>.....................] - ETA: 1s - loss: 0.0000e+00 - accuracy: 0.9120
# 17/46 [==========>...................] - ETA: 1s - loss: 0.0000e+00 - accuracy: 0.9124
# 19/46 [===========>..................] - ETA: 1s - loss: 0.0000e+00 - accuracy: 0.9131
# 21/46 [============>.................] - ETA: 0s - loss: 0.0000e+00 - accuracy: 0.9141
# 23/46 [==============>...............] - ETA: 0s - loss: 0.0000e+00 - accuracy: 0.9149
# 25/46 [===============>..............] - ETA: 0s - loss: 0.0000e+00 - accuracy: 0.9152
# 27/46 [================>.............] - ETA: 0s - loss: 0.0000e+00 - accuracy: 0.9152
# 29/46 [=================>............] - ETA: 0s - loss: 0.0000e+00 - accuracy: 0.9154
# 31/46 [===================>..........] - ETA: 0s - loss: 0.0000e+00 - accuracy: 0.9145
# 33/46 [====================>.........] - ETA: 0s - loss: 0.0000e+00 - accuracy: 0.9145
# 35/46 [=====================>........] - ETA: 0s - loss: 0.0000e+00 - accuracy: 0.9148
# 37/46 [=======================>......] - ETA: 0s - loss: 0.0000e+00 - accuracy: 0.9150
# 39/46 [========================>.....] - ETA: 0s - loss: 0.0000e+00 - accuracy: 0.9147
# 41/46 [=========================>....] - ETA: 0s - loss: 0.0000e+00 - accuracy: 0.9154
# 43/46 [===========================>..] - ETA: 0s - loss: 0.0000e+00 - accuracy: 0.9156
# 45/46 [============================>.] - ETA: 0s - loss: 0.0000e+00 - accuracy: 0.9156
# 46/46 [==============================] - 6s 38ms/step - loss: 0.0000e+00 - accuracy: 0.9156
# loss: 0.0000
# accuracy: 0.9156

# %%
# Model Summary
model.summary()
# Out:
# Model: "random_forest_model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
# =================================================================
# Total params: 1 (1.00 Byte)
# Trainable params: 0 (0.00 Byte)
# Non-trainable params: 1 (1.00 Byte)
# _________________________________________________________________
# Type: "RANDOM_FOREST"
# Task: CLASSIFICATION
# Label: "__LABEL"
#
# Input Features (16):
# 	GrayLevelNonUniformity
# 	GrayLevelNonUniformityNormalized
# 	GrayLevelVariance
# 	HighGrayLevelRunEmphasis
# 	LongRunEmphasis
# 	LongRunHighGrayLevelEmphasis
# 	LongRunLowGrayLevelEmphasis
# 	LowGrayLevelRunEmphasis
# 	RunEntropy
# 	RunLengthNonUniformity
# 	RunLengthNonUniformityNormalized
# 	RunPercentage
# 	RunVariance
# 	ShortRunEmphasis
# 	ShortRunHighGrayLevelEmphasis
# 	ShortRunLowGrayLevelEmphasis
#
# Trained with weights
#
# Variable Importance: INV_MEAN_MIN_DEPTH:
#     1.     "LongRunHighGrayLevelEmphasis"  0.172174 ################
#     2.         "HighGrayLevelRunEmphasis"  0.157641 #############
#     3.          "LowGrayLevelRunEmphasis"  0.133400 ########
#     4.     "ShortRunLowGrayLevelEmphasis"  0.130098 ########
#     5.    "ShortRunHighGrayLevelEmphasis"  0.129175 ########
#     6.                       "RunEntropy"  0.114801 #####
#     7.           "GrayLevelNonUniformity"  0.109267 ####
#     8.      "LongRunLowGrayLevelEmphasis"  0.104746 ###
#     9.                      "RunVariance"  0.091712 #
#    10. "GrayLevelNonUniformityNormalized"  0.091451 #
#    11.                "GrayLevelVariance"  0.088391
#    12. "RunLengthNonUniformityNormalized"  0.088097
#    13.                 "ShortRunEmphasis"  0.087474
#    14.                    "RunPercentage"  0.084887
#    15.                  "LongRunEmphasis"  0.083828
#    16.           "RunLengthNonUniformity"  0.083753
#
# Variable Importance: NUM_AS_ROOT:
#     1.          "LowGrayLevelRunEmphasis" 77.000000 ################
#     2.         "HighGrayLevelRunEmphasis" 71.000000 ##############
#     3.     "ShortRunLowGrayLevelEmphasis" 62.000000 ############
#     4.      "LongRunLowGrayLevelEmphasis" 29.000000 #####
#     5.     "LongRunHighGrayLevelEmphasis" 23.000000 ####
#     6.    "ShortRunHighGrayLevelEmphasis" 19.000000 ###
#     7.                       "RunEntropy"  7.000000 #
#     8.           "GrayLevelNonUniformity"  5.000000
#     9. "GrayLevelNonUniformityNormalized"  5.000000
#    10.                "GrayLevelVariance"  2.000000
#
# Variable Importance: NUM_NODES:
#     1.                       "RunEntropy" 65188.000000 ################
#     2.           "GrayLevelNonUniformity" 65055.000000 ###############
#     3.     "LongRunHighGrayLevelEmphasis" 62287.000000 ##############
#     4.                "GrayLevelVariance" 61665.000000 #############
#     5. "GrayLevelNonUniformityNormalized" 56468.000000 ##########
#     6.     "ShortRunLowGrayLevelEmphasis" 53759.000000 ########
#     7.    "ShortRunHighGrayLevelEmphasis" 50995.000000 #######
#     8.                      "RunVariance" 50458.000000 ######
#     9.      "LongRunLowGrayLevelEmphasis" 50428.000000 ######
#    10.         "HighGrayLevelRunEmphasis" 49138.000000 ######
#    11.          "LowGrayLevelRunEmphasis" 48852.000000 #####
#    12. "RunLengthNonUniformityNormalized" 45848.000000 ####
#    13.                 "ShortRunEmphasis" 44865.000000 ###
#    14.                  "LongRunEmphasis" 43041.000000 ##
#    15.           "RunLengthNonUniformity" 41621.000000 #
#    16.                    "RunPercentage" 39181.000000
#
# Variable Importance: SUM_SCORE:
#     1.     "LongRunHighGrayLevelEmphasis" 6318232.285505 ################
#     2.         "HighGrayLevelRunEmphasis" 6271634.931348 ###############
#     3.          "LowGrayLevelRunEmphasis" 5115669.699149 ############
#     4.     "ShortRunLowGrayLevelEmphasis" 4727440.646744 ##########
#     5.    "ShortRunHighGrayLevelEmphasis" 4205589.399316 #########
#     6.                       "RunEntropy" 3753111.999781 #######
#     7.           "GrayLevelNonUniformity" 3467714.226457 ######
#     8.      "LongRunLowGrayLevelEmphasis" 3092802.080073 #####
#     9. "GrayLevelNonUniformityNormalized" 2019180.784771 ##
#    10.                      "RunVariance" 1959211.886158 ##
#    11.                "GrayLevelVariance" 1878299.209964 #
#    12. "RunLengthNonUniformityNormalized" 1577876.585308
#    13.                 "ShortRunEmphasis" 1534972.685342
#    14.                  "LongRunEmphasis" 1398712.269453
#    15.                    "RunPercentage" 1354054.860727
#    16.           "RunLengthNonUniformity" 1305154.508107
#
#
#
# Winner takes all: true
# Out-of-bag evaluation: accuracy:0.858971 logloss:0.49983
# Number of trees: 300
# Total number of nodes: 1657998
#
# Number of nodes by tree:
# Count: 300 Average: 5526.66 StdDev: 366.889
# Min: 4359 Max: 6459 Ignored: 0
# ----------------------------------------------
# [ 4359, 4464)  2   0.67%   0.67% #
# [ 4464, 4569)  1   0.33%   1.00%
# [ 4569, 4674)  1   0.33%   1.33%
# [ 4674, 4779)  4   1.33%   2.67% #
# [ 4779, 4884)  6   2.00%   4.67% ##
# [ 4884, 4989) 11   3.67%   8.33% ###
# [ 4989, 5094) 15   5.00%  13.33% ####
# [ 5094, 5199) 21   7.00%  20.33% #####
# [ 5199, 5304) 23   7.67%  28.00% ######
# [ 5304, 5409) 21   7.00%  35.00% #####
# [ 5409, 5514) 26   8.67%  43.67% #######
# [ 5514, 5619) 29   9.67%  53.33% #######
# [ 5619, 5724) 38  12.67%  66.00% ##########
# [ 5724, 5829) 39  13.00%  79.00% ##########
# [ 5829, 5934) 30  10.00%  89.00% ########
# [ 5934, 6039) 16   5.33%  94.33% ####
# [ 6039, 6144)  8   2.67%  97.00% ##
# [ 6144, 6249)  6   2.00%  99.00% ##
# [ 6249, 6354)  1   0.33%  99.33%
# [ 6354, 6459]  2   0.67% 100.00% #
#
# Depth by leafs:
# Count: 829149 Average: 13.3248 StdDev: 1.91642
# Min: 3 Max: 15 Ignored: 0
# ----------------------------------------------
# [  3,  4)      1   0.00%   0.00%
# [  4,  5)     31   0.00%   0.00%
# [  5,  6)    442   0.05%   0.06%
# [  6,  7)   1802   0.22%   0.27%
# [  7,  8)   5106   0.62%   0.89%
# [  8,  9)  11657   1.41%   2.30%
# [  9, 10)  23099   2.79%   5.08% #
# [ 10, 11)  39774   4.80%   9.88% #
# [ 11, 12)  63626   7.67%  17.55% ##
# [ 12, 13)  90777  10.95%  28.50% ###
# [ 13, 14) 118915  14.34%  42.84% ####
# [ 14, 15) 143437  17.30%  60.14% ####
# [ 15, 15] 330482  39.86% 100.00% ##########
#
# Number of training obs by leaf:
# Count: 829149 Average: 114.136 StdDev: 551.992
# Min: 5 Max: 28810 Ignored: 0
# ----------------------------------------------
# [     5,  1445) 818972  98.77%  98.77% ##########
# [  1445,  2885)   6020   0.73%  99.50%
# [  2885,  4325)   1841   0.22%  99.72%
# [  4325,  5766)    755   0.09%  99.81%
# [  5766,  7206)    443   0.05%  99.87%
# [  7206,  8646)    314   0.04%  99.90%
# [  8646, 10087)    220   0.03%  99.93%
# [ 10087, 11527)    158   0.02%  99.95%
# [ 11527, 12967)    134   0.02%  99.96%
# [ 12967, 14408)     93   0.01%  99.98%
# [ 14408, 15848)     64   0.01%  99.98%
# [ 15848, 17288)     51   0.01%  99.99%
# [ 17288, 18728)     40   0.00%  99.99%
# [ 18728, 20169)     21   0.00% 100.00%
# [ 20169, 21609)     11   0.00% 100.00%
# [ 21609, 23049)      5   0.00% 100.00%
# [ 23049, 24490)      5   0.00% 100.00%
# [ 24490, 25930)      1   0.00% 100.00%
# [ 25930, 27370)      0   0.00% 100.00%
# [ 27370, 28810]      1   0.00% 100.00%
#
# Attribute in nodes:
# 	65188 : RunEntropy [NUMERICAL]
# 	65055 : GrayLevelNonUniformity [NUMERICAL]
# 	62287 : LongRunHighGrayLevelEmphasis [NUMERICAL]
# 	61665 : GrayLevelVariance [NUMERICAL]
# 	56468 : GrayLevelNonUniformityNormalized [NUMERICAL]
# 	53759 : ShortRunLowGrayLevelEmphasis [NUMERICAL]
# 	50995 : ShortRunHighGrayLevelEmphasis [NUMERICAL]
# 	50458 : RunVariance [NUMERICAL]
# 	50428 : LongRunLowGrayLevelEmphasis [NUMERICAL]
# 	49138 : HighGrayLevelRunEmphasis [NUMERICAL]
# 	48852 : LowGrayLevelRunEmphasis [NUMERICAL]
# 	45848 : RunLengthNonUniformityNormalized [NUMERICAL]
# 	44865 : ShortRunEmphasis [NUMERICAL]
# 	43041 : LongRunEmphasis [NUMERICAL]
# 	41621 : RunLengthNonUniformity [NUMERICAL]
# 	39181 : RunPercentage [NUMERICAL]
#
# Attribute in nodes with depth <= 0:
# 	77 : LowGrayLevelRunEmphasis [NUMERICAL]
# 	71 : HighGrayLevelRunEmphasis [NUMERICAL]
# 	62 : ShortRunLowGrayLevelEmphasis [NUMERICAL]
# 	29 : LongRunLowGrayLevelEmphasis [NUMERICAL]
# 	23 : LongRunHighGrayLevelEmphasis [NUMERICAL]
# 	19 : ShortRunHighGrayLevelEmphasis [NUMERICAL]
# 	7 : RunEntropy [NUMERICAL]
# 	5 : GrayLevelNonUniformityNormalized [NUMERICAL]
# 	5 : GrayLevelNonUniformity [NUMERICAL]
# 	2 : GrayLevelVariance [NUMERICAL]
#
# Attribute in nodes with depth <= 1:
# 	212 : HighGrayLevelRunEmphasis [NUMERICAL]
# 	197 : LongRunHighGrayLevelEmphasis [NUMERICAL]
# 	117 : LowGrayLevelRunEmphasis [NUMERICAL]
# 	110 : ShortRunHighGrayLevelEmphasis [NUMERICAL]
# 	101 : ShortRunLowGrayLevelEmphasis [NUMERICAL]
# 	49 : LongRunLowGrayLevelEmphasis [NUMERICAL]
# 	47 : RunEntropy [NUMERICAL]
# 	23 : GrayLevelNonUniformity [NUMERICAL]
# 	14 : GrayLevelNonUniformityNormalized [NUMERICAL]
# 	12 : GrayLevelVariance [NUMERICAL]
# 	5 : ShortRunEmphasis [NUMERICAL]
# 	4 : RunVariance [NUMERICAL]
# 	4 : RunLengthNonUniformityNormalized [NUMERICAL]
# 	2 : RunPercentage [NUMERICAL]
# 	2 : LongRunEmphasis [NUMERICAL]
# 	1 : RunLengthNonUniformity [NUMERICAL]
#
# Attribute in nodes with depth <= 2:
# 	417 : LongRunHighGrayLevelEmphasis [NUMERICAL]
# 	352 : HighGrayLevelRunEmphasis [NUMERICAL]
# 	247 : ShortRunHighGrayLevelEmphasis [NUMERICAL]
# 	219 : LowGrayLevelRunEmphasis [NUMERICAL]
# 	203 : ShortRunLowGrayLevelEmphasis [NUMERICAL]
# 	143 : RunEntropy [NUMERICAL]
# 	105 : LongRunLowGrayLevelEmphasis [NUMERICAL]
# 	85 : GrayLevelNonUniformity [NUMERICAL]
# 	62 : RunVariance [NUMERICAL]
# 	47 : ShortRunEmphasis [NUMERICAL]
# 	46 : GrayLevelNonUniformityNormalized [NUMERICAL]
# 	45 : RunLengthNonUniformityNormalized [NUMERICAL]
# 	39 : RunPercentage [NUMERICAL]
# 	33 : GrayLevelVariance [NUMERICAL]
# 	32 : LongRunEmphasis [NUMERICAL]
# 	25 : RunLengthNonUniformity [NUMERICAL]
#
# Attribute in nodes with depth <= 3:
# 	863 : LongRunHighGrayLevelEmphasis [NUMERICAL]
# 	588 : HighGrayLevelRunEmphasis [NUMERICAL]
# 	411 : ShortRunHighGrayLevelEmphasis [NUMERICAL]
# 	405 : ShortRunLowGrayLevelEmphasis [NUMERICAL]
# 	403 : RunEntropy [NUMERICAL]
# 	372 : LowGrayLevelRunEmphasis [NUMERICAL]
# 	259 : GrayLevelNonUniformity [NUMERICAL]
# 	240 : LongRunLowGrayLevelEmphasis [NUMERICAL]
# 	153 : ShortRunEmphasis [NUMERICAL]
# 	145 : RunLengthNonUniformityNormalized [NUMERICAL]
# 	137 : GrayLevelNonUniformityNormalized [NUMERICAL]
# 	125 : RunVariance [NUMERICAL]
# 	108 : RunPercentage [NUMERICAL]
# 	105 : RunLengthNonUniformity [NUMERICAL]
# 	102 : GrayLevelVariance [NUMERICAL]
# 	83 : LongRunEmphasis [NUMERICAL]
#
# Attribute in nodes with depth <= 5:
# 	2584 : LongRunHighGrayLevelEmphasis [NUMERICAL]
# 	1835 : RunEntropy [NUMERICAL]
# 	1460 : HighGrayLevelRunEmphasis [NUMERICAL]
# 	1445 : GrayLevelNonUniformity [NUMERICAL]
# 	1338 : ShortRunLowGrayLevelEmphasis [NUMERICAL]
# 	1237 : LowGrayLevelRunEmphasis [NUMERICAL]
# 	1121 : ShortRunHighGrayLevelEmphasis [NUMERICAL]
# 	1044 : RunLengthNonUniformityNormalized [NUMERICAL]
# 	975 : ShortRunEmphasis [NUMERICAL]
# 	936 : LongRunLowGrayLevelEmphasis [NUMERICAL]
# 	878 : GrayLevelNonUniformityNormalized [NUMERICAL]
# 	779 : RunLengthNonUniformity [NUMERICAL]
# 	746 : GrayLevelVariance [NUMERICAL]
# 	742 : RunVariance [NUMERICAL]
# 	674 : RunPercentage [NUMERICAL]
# 	564 : LongRunEmphasis [NUMERICAL]
#
# Condition type in nodes:
# 	828849 : HigherCondition
# Condition type in nodes with depth <= 0:
# 	300 : HigherCondition
# Condition type in nodes with depth <= 1:
# 	900 : HigherCondition
# Condition type in nodes with depth <= 2:
# 	2100 : HigherCondition
# Condition type in nodes with depth <= 3:
# 	4499 : HigherCondition
# Condition type in nodes with depth <= 5:
# 	18358 : HigherCondition
# Node format: NOT_SET
#
# Training OOB:
# 	trees: 1, Out-of-bag evaluation: accuracy:0.822893 logloss:6.38357
# 	trees: 11, Out-of-bag evaluation: accuracy:0.835287 logloss:2.52573
# 	trees: 21, Out-of-bag evaluation: accuracy:0.846303 logloss:1.59921
# 	trees: 31, Out-of-bag evaluation: accuracy:0.851615 logloss:1.25828
# 	trees: 41, Out-of-bag evaluation: accuracy:0.853527 logloss:1.06167
# 	trees: 51, Out-of-bag evaluation: accuracy:0.853905 logloss:0.935544
# 	trees: 61, Out-of-bag evaluation: accuracy:0.85519 logloss:0.86434
# 	trees: 71, Out-of-bag evaluation: accuracy:0.856633 logloss:0.804319
# 	trees: 81, Out-of-bag evaluation: accuracy:0.856523 logloss:0.763559
# 	trees: 91, Out-of-bag evaluation: accuracy:0.857237 logloss:0.721509
# 	trees: 101, Out-of-bag evaluation: accuracy:0.857227 logloss:0.687219
# 	trees: 111, Out-of-bag evaluation: accuracy:0.857808 logloss:0.667123
# 	trees: 121, Out-of-bag evaluation: accuracy:0.857437 logloss:0.643271
# 	trees: 131, Out-of-bag evaluation: accuracy:0.857997 logloss:0.621311
# 	trees: 141, Out-of-bag evaluation: accuracy:0.858495 logloss:0.603673
# 	trees: 151, Out-of-bag evaluation: accuracy:0.858119 logloss:0.591625
# 	trees: 161, Out-of-bag evaluation: accuracy:0.858294 logloss:0.583473
# 	trees: 171, Out-of-bag evaluation: accuracy:0.85814 logloss:0.572547
# 	trees: 181, Out-of-bag evaluation: accuracy:0.858123 logloss:0.560883
# 	trees: 191, Out-of-bag evaluation: accuracy:0.858606 logloss:0.552956
# 	trees: 201, Out-of-bag evaluation: accuracy:0.858455 logloss:0.549147
# 	trees: 211, Out-of-bag evaluation: accuracy:0.858645 logloss:0.543726
# 	trees: 221, Out-of-bag evaluation: accuracy:0.858735 logloss:0.538839
# 	trees: 231, Out-of-bag evaluation: accuracy:0.858914 logloss:0.534307
# 	trees: 241, Out-of-bag evaluation: accuracy:0.859068 logloss:0.526838
# 	trees: 251, Out-of-bag evaluation: accuracy:0.85905 logloss:0.521585
# 	trees: 261, Out-of-bag evaluation: accuracy:0.858648 logloss:0.517414
# 	trees: 271, Out-of-bag evaluation: accuracy:0.859026 logloss:0.513501
# 	trees: 281, Out-of-bag evaluation: accuracy:0.858888 logloss:0.5086
# 	trees: 291, Out-of-bag evaluation: accuracy:0.85889 logloss:0.504101
# 	trees: 300, Out-of-bag evaluation: accuracy:0.858971 logloss:0.49983

# %%
# Model features
model.make_inspector().features()
# Out:
# ["GrayLevelNonUniformity" (1; #0),
#  "GrayLevelNonUniformityNormalized" (1; #1),
#  "GrayLevelVariance" (1; #2),
#  "HighGrayLevelRunEmphasis" (1; #3),
#  "LongRunEmphasis" (1; #4),
#  "LongRunHighGrayLevelEmphasis" (1; #5),
#  "LongRunLowGrayLevelEmphasis" (1; #6),
#  "LowGrayLevelRunEmphasis" (1; #7),
#  "RunEntropy" (1; #8),
#  "RunLengthNonUniformity" (1; #9),
#  "RunLengthNonUniformityNormalized" (1; #10),
#  "RunPercentage" (1; #11),
#  "RunVariance" (1; #12),
#  "ShortRunEmphasis" (1; #13),
#  "ShortRunHighGrayLevelEmphasis" (1; #14),
#  "ShortRunLowGrayLevelEmphasis" (1; #15)]

# %%
# Feature importance
model.make_inspector().variable_importances()
# Out:
# {'INV_MEAN_MIN_DEPTH': [("LongRunHighGrayLevelEmphasis" (1; #5),
#    0.17217354022690082),
#   ("HighGrayLevelRunEmphasis" (1; #3), 0.1576413451887398),
#   ("LowGrayLevelRunEmphasis" (1; #7), 0.13340027482496453),
#   ("ShortRunLowGrayLevelEmphasis" (1; #15), 0.13009809894418764),
#   ("ShortRunHighGrayLevelEmphasis" (1; #14), 0.1291752471766399),
#   ("RunEntropy" (1; #8), 0.11480076474909671),
#   ("GrayLevelNonUniformity" (1; #0), 0.10926743391806469),
#   ("LongRunLowGrayLevelEmphasis" (1; #6), 0.10474609742252128),
#   ("RunVariance" (1; #12), 0.09171176644371418),
#   ("GrayLevelNonUniformityNormalized" (1; #1), 0.09145090245799209),
#   ("GrayLevelVariance" (1; #2), 0.08839142317373908),
#   ("RunLengthNonUniformityNormalized" (1; #10), 0.08809703396441135),
#   ("ShortRunEmphasis" (1; #13), 0.0874742403351983),
#   ("RunPercentage" (1; #11), 0.08488658728858069),
#   ("LongRunEmphasis" (1; #4), 0.08382801226263537),
#   ("RunLengthNonUniformity" (1; #9), 0.08375320763068235)],
#  'NUM_AS_ROOT': [("LowGrayLevelRunEmphasis" (1; #7), 77.0),
#   ("HighGrayLevelRunEmphasis" (1; #3), 71.0),
#   ("ShortRunLowGrayLevelEmphasis" (1; #15), 62.0),
#   ("LongRunLowGrayLevelEmphasis" (1; #6), 29.0),
#   ("LongRunHighGrayLevelEmphasis" (1; #5), 23.0),
#   ("ShortRunHighGrayLevelEmphasis" (1; #14), 19.0),
#   ("RunEntropy" (1; #8), 7.0),
#   ("GrayLevelNonUniformity" (1; #0), 5.0),
#   ("GrayLevelNonUniformityNormalized" (1; #1), 5.0),
#   ("GrayLevelVariance" (1; #2), 2.0)],
#  'SUM_SCORE': [("LongRunHighGrayLevelEmphasis" (1; #5), 6318232.285505107),
#   ("HighGrayLevelRunEmphasis" (1; #3), 6271634.931348083),
#   ("LowGrayLevelRunEmphasis" (1; #7), 5115669.699148921),
#   ("ShortRunLowGrayLevelEmphasis" (1; #15), 4727440.646744299),
#   ("ShortRunHighGrayLevelEmphasis" (1; #14), 4205589.399316254),
#   ("RunEntropy" (1; #8), 3753111.999780527),
#   ("GrayLevelNonUniformity" (1; #0), 3467714.2264573765),
#   ("LongRunLowGrayLevelEmphasis" (1; #6), 3092802.080072728),
#   ("GrayLevelNonUniformityNormalized" (1; #1), 2019180.7847713856),
#   ("RunVariance" (1; #12), 1959211.8861580356),
#   ("GrayLevelVariance" (1; #2), 1878299.2099638276),
#   ("RunLengthNonUniformityNormalized" (1; #10), 1577876.5853077814),
#   ("ShortRunEmphasis" (1; #13), 1534972.6853421323),
#   ("LongRunEmphasis" (1; #4), 1398712.2694528894),
#   ("RunPercentage" (1; #11), 1354054.8607267765),
#   ("RunLengthNonUniformity" (1; #9), 1305154.508107166)],
#  'NUM_NODES': [("RunEntropy" (1; #8), 65188.0),
#   ("GrayLevelNonUniformity" (1; #0), 65055.0),
#   ("LongRunHighGrayLevelEmphasis" (1; #5), 62287.0),
#   ("GrayLevelVariance" (1; #2), 61665.0),
#   ("GrayLevelNonUniformityNormalized" (1; #1), 56468.0),
#   ("ShortRunLowGrayLevelEmphasis" (1; #15), 53759.0),
#   ("ShortRunHighGrayLevelEmphasis" (1; #14), 50995.0),
#   ("RunVariance" (1; #12), 50458.0),
#   ("LongRunLowGrayLevelEmphasis" (1; #6), 50428.0),
#   ("HighGrayLevelRunEmphasis" (1; #3), 49138.0),
#   ("LowGrayLevelRunEmphasis" (1; #7), 48852.0),
#   ("RunLengthNonUniformityNormalized" (1; #10), 45848.0),
#   ("ShortRunEmphasis" (1; #13), 44865.0),
#   ("LongRunEmphasis" (1; #4), 43041.0),
#   ("RunLengthNonUniformity" (1; #9), 41621.0),
#   ("RunPercentage" (1; #11), 39181.0)]}

# %%
# Model self evaluation
model.make_inspector().evaluation()
# Out:
# Evaluation(num_examples=315452, accuracy=0.8589712535630526, loss=0.4998301366986106, rmse=None, ndcg=None, aucs=None, auuc=None, qini=None)

# %%
logs = model.make_inspector().training_logs()

plt.figure(figsize=(12, 4))
plt.subplot(1, 2, 1)
plt.plot([log.num_trees for log in logs], [log.evaluation.accuracy for log in logs])
plt.xlabel("Number of trees")
plt.ylabel("Accuracy (out-of-bag)")
plt.subplot(1, 2, 2)
plt.plot([log.num_trees for log in logs], [log.evaluation.loss for log in logs])
plt.xlabel("Number of trees")
plt.ylabel("Logloss (out-of-bag)")
plt.show()

# %% [markdown]
# Calculate the score of our hold-out validation dataset

# %%
predictions = model.predict(val_ds)
y_true      = validation_data["label"]

from sklearn.metrics import roc_auc_score
ROC_AUC = roc_auc_score(y_true, predictions)
print("The ROC AUC score is %.5f" % ROC_AUC )
# Out:
#  1/46 [..............................] - ETA: 4s
#  3/46 [>.............................] - ETA: 1s
#  5/46 [==>...........................] - ETA: 1s
#  7/46 [===>..........................] - ETA: 1s
#  9/46 [====>.........................] - ETA: 1s
# 11/46 [======>.......................] - ETA: 1s
# 13/46 [=======>......................] - ETA: 1s
# 15/46 [========>.....................] - ETA: 1s
# 17/46 [==========>...................] - ETA: 1s
# 19/46 [===========>..................] - ETA: 1s
# 21/46 [============>.................] - ETA: 0s
# 23/46 [==============>...............] - ETA: 0s
# 25/46 [===============>..............] - ETA: 0s
# 27/46 [================>.............] - ETA: 0s
# 29/46 [=================>............] - ETA: 0s
# 31/46 [===================>..........] - ETA: 0s
# 33/46 [====================>.........] - ETA: 0s
# 35/46 [=====================>........] - ETA: 0s
# 37/46 [=======================>......] - ETA: 0s
# 39/46 [========================>.....] - ETA: 0s
# 41/46 [=========================>....] - ETA: 0s
# 43/46 [===========================>..] - ETA: 0s
# 45/46 [============================>.] - ETA: 0s
# 46/46 [==============================] - 2s 36ms/step
# The ROC AUC score is 0.94561

# %%
# Compute binary classification metrics with sklearn
import numpy as np
from sklearn.metrics import (
    accuracy_score,
    precision_score,
    recall_score,
    f1_score,
    roc_auc_score,
    average_precision_score,
    confusion_matrix,
    classification_report,
    matthews_corrcoef,
    log_loss,
    brier_score_loss,
)

# Get predictions (probabilities or class labels)
preds = model.predict(test_ds)
# If model outputs probabilities, convert to labels by threshold 0.5
if preds.ndim == 2:
    # For TFDF classification, preds may be class probabilities with shape (N, 2)
    if preds.shape[1] == 2:
        pos_probs = preds[:, 1]
    else:
        # If single-probability column (positive class)
        pos_probs = preds[:, -1]
    y_pred = (pos_probs >= 0.5).astype(int)
else:
    # Already class labels
    y_pred = preds.astype(int)
    pos_probs = None

# Ground truth labels (must be 0/1 integers)
y_true = test_data["label"].astype(int).to_numpy()

# Core metrics
metrics = {}
metrics["accuracy"] = accuracy_score(y_true, y_pred)
metrics["precision"] = precision_score(y_true, y_pred, zero_division=0)
metrics["recall"] = recall_score(y_true, y_pred, zero_division=0)
metrics["f1"] = f1_score(y_true, y_pred, zero_division=0)
metrics["mcc"] = matthews_corrcoef(y_true, y_pred)

# Probabilistic metrics (only if we have probabilities)
if pos_probs is not None:
    metrics["roc_auc"] = roc_auc_score(y_true, pos_probs)
    metrics["pr_auc"] = average_precision_score(y_true, pos_probs)
    metrics["log_loss"] = log_loss(y_true, pos_probs, labels=[0,1])
    metrics["brier_score"] = brier_score_loss(y_true, pos_probs)

# Confusion matrix and detailed report
cm = confusion_matrix(y_true, y_pred, labels=[0,1])
report = classification_report(y_true, y_pred, digits=4)

print("Sklearn binary metrics:")
for k, v in metrics.items():
    print(f"{k}: {v:.4f}")
print("\nConfusion matrix:\n", cm)
print("\nClassification report:\n", report)
# Out:
#  1/91 [..............................] - ETA: 9s
#  3/91 [..............................] - ETA: 3s
#  5/91 [>.............................] - ETA: 3s
#  7/91 [=>............................] - ETA: 3s
#  9/91 [=>............................] - ETA: 3s
# 11/91 [==>...........................] - ETA: 2s
# 13/91 [===>..........................] - ETA: 2s
# 15/91 [===>..........................] - ETA: 2s
# 17/91 [====>.........................] - ETA: 2s
# 19/91 [=====>........................] - ETA: 2s
# 21/91 [=====>........................] - ETA: 2s
# 23/91 [======>.......................] - ETA: 2s
# 25/91 [=======>......................] - ETA: 2s
# 27/91 [=======>......................] - ETA: 2s
# 29/91 [========>.....................] - ETA: 2s
# 31/91 [=========>....................] - ETA: 2s
# 33/91 [=========>....................] - ETA: 2s
# 35/91 [==========>...................] - ETA: 2s
# 37/91 [===========>..................] - ETA: 1s
# 39/91 [===========>..................] - ETA: 1s
# 41/91 [============>.................] - ETA: 1s
# 43/91 [=============>................] - ETA: 1s
# 45/91 [=============>................] - ETA: 1s
# 47/91 [==============>...............] - ETA: 1s
# 49/91 [===============>..............] - ETA: 1s
# 51/91 [===============>..............] - ETA: 1s
# 53/91 [================>.............] - ETA: 1s
# 55/91 [=================>............] - ETA: 1s
# 57/91 [=================>............] - ETA: 1s
# 59/91 [==================>...........] - ETA: 1s
# 61/91 [===================>..........] - ETA: 1s
# 63/91 [===================>..........] - ETA: 1s
# 65/91 [====================>.........] - ETA: 0s
# 67/91 [=====================>........] - ETA: 0s
# 69/91 [=====================>........] - ETA: 0s
# 71/91 [======================>.......] - ETA: 0s
# 73/91 [=======================>......] - ETA: 0s
# 75/91 [=======================>......] - ETA: 0s
# 77/91 [========================>.....] - ETA: 0s
# 79/91 [=========================>....] - ETA: 0s
# 81/91 [=========================>....] - ETA: 0s
# 83/91 [==========================>...] - ETA: 0s
# 85/91 [===========================>..] - ETA: 0s
# 87/91 [===========================>..] - ETA: 0s
# 89/91 [============================>.] - ETA: 0s
# 91/91 [==============================] - 3s 36ms/step
# Sklearn binary metrics:
# accuracy: 0.9149
# precision: 0.4151
# recall: 0.7990
# f1: 0.5463
# mcc: 0.5376
# roc_auc: 0.9430
# pr_auc: 0.6557
# log_loss: 0.2071
# brier_score: 0.0619
#
# Confusion matrix:
#  [[77837  6511]
#  [ 1162  4620]]
#
# Classification report:
#                precision    recall  f1-score   support
#
#            0     0.9853    0.9228    0.9530     84348
#            1     0.4151    0.7990    0.5463      5782
#
#     accuracy                         0.9149     90130
#    macro avg     0.7002    0.8609    0.7497     90130
# weighted avg     0.9487    0.9149    0.9269     90130
