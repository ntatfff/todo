# %%
# Import packages and modules
import numpy  as np
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow_decision_forests as tfdf

from sklearn.model_selection import train_test_split
# Out:
# 2026-07-04 08:48:25.270643: I tensorflow/core/util/port.cc:113] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2026-07-04 08:48:25.309821: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2026-07-04 08:48:31.110207: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
# Check the version of TensorFlow Decision Forests
print("Found TensorFlow Decision Forests v" + tfdf.__version__)
# Out:
# Found TensorFlow Decision Forests v1.9.1

# %%
datasetPath = 'dataset/firstorder/kernel5-radius5/dataset.csv'

# %%
# Parameters
datasetPath = "dataset/glrlm/kernel5-radius5/300.dataset.csv"

# %%
# train/validation/test = 70/10/20
dataset = pd.read_csv(datasetPath)

train_data, temp_data = train_test_split(dataset, test_size=0.3, random_state=42)
validation_data, test_data = train_test_split(temp_data, test_size=2/3, random_state=42)

# %%
from sklearn.utils.class_weight import compute_class_weight

# tinh class weight tren tap train
classes = np.array([0, 1])
weights = compute_class_weight(class_weight="balanced", classes=classes, y=train_data["label"])
class_weight = {0: weights[0], 1: weights[1]}

# gan sample_weight cho tung dong
train_data["sample_weight"] = train_data["label"].map(class_weight)
validation_data["sample_weight"] = validation_data["label"].map(class_weight)
test_data["sample_weight"] = test_data["label"].map(class_weight)

# Convert the dataset into a TensorFlow dataset.
train_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    train_data, label="label", weight="sample_weight"
)         
val_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    validation_data, label="label", weight="sample_weight"
)
test_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    test_data, label="label", weight="sample_weight"
)
# Out:
# 2026-07-04 08:48:43.490477: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:984] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2026-07-04 08:48:43.492054: W tensorflow/core/common_runtime/gpu/gpu_device.cc:2251] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...

# %%
import keras

# %%
# %%time

# Train a Gradient Boosted Trees model.
model = tfdf.keras.GradientBoostedTreesModel()

# Add evaluation metrics
model.compile(
    metrics=["accuracy"]
)
model.fit(x=train_ds)

# # Train a Gradient Boosted Trees model.
# model = tfdf.keras.GradientBoostedTreesModel(num_trees=1500)
# model.fit(train_ds)
# Out:
# Use /tmp/tmpl_3ux88g as temporary training directory
# Reading training dataset...
# [WARNING 26-07-04 08:48:43.6530 UTC gradient_boosted_trees.cc:1840] "goss_alpha" set but "sampling_method" not equal to "GOSS".
# [WARNING 26-07-04 08:48:43.6531 UTC gradient_boosted_trees.cc:1851] "goss_beta" set but "sampling_method" not equal to "GOSS".
# [WARNING 26-07-04 08:48:43.6531 UTC gradient_boosted_trees.cc:1865] "selective_gradient_boosting_ratio" set but "sampling_method" not equal to "SELGB".
# Training dataset read in 0:00:03.364113. Found 235709 examples.
# Training model...
# Model trained in 0:00:44.242736
# Compiling model...
# [INFO 26-07-04 08:49:31.2751 UTC kernel.cc:1233] Loading model from path /tmp/tmpl_3ux88g/model/ with prefix bc9b1cdb2789434d
# [INFO 26-07-04 08:49:31.2858 UTC quick_scorer_extended.cc:911] The binary was compiled without AVX2 support, but your CPU supports it. Enable it for faster model inference.
# [INFO 26-07-04 08:49:31.2865 UTC abstract_model.cc:1362] Engine "GradientBoostedTreesQuickScorerExtended" built
# [INFO 26-07-04 08:49:31.2866 UTC kernel.cc:1061] Use fast generic engine
# Model compiled.
# CPU times: user 5min 36s, sys: 2.84 s, total: 5min 39s
# Wall time: 52.3 s

# %%
# Evaluate the model
evaluate = model.evaluate(val_ds, return_dict=True)
print()

for name, value in evaluate.items():
    print(f"{name}: {value:.4f}")
# Out:
# WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
#  1/34 [..............................] - ETA: 1:37 - loss: 0.0000e+00 - accuracy: 0.9040
# 14/34 [===========>..................] - ETA: 0s - loss: 0.0000e+00 - accuracy: 0.8987
# 26/34 [=====================>........] - ETA: 0s - loss: 0.0000e+00 - accuracy: 0.8986
# 34/34 [==============================] - 3s 4ms/step - loss: 0.0000e+00 - accuracy: 0.8964
# loss: 0.0000
# accuracy: 0.8964

# %%
# Model Summary
model.summary()
# Out:
# Model: "gradient_boosted_trees_model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
# =================================================================
# Total params: 1 (1.00 Byte)
# Trainable params: 0 (0.00 Byte)
# Non-trainable params: 1 (1.00 Byte)
# _________________________________________________________________
# Type: "GRADIENT_BOOSTED_TREES"
# Task: CLASSIFICATION
# Label: "__LABEL"
#
# Input Features (16):
# 	GrayLevelNonUniformity
# 	GrayLevelNonUniformityNormalized
# 	GrayLevelVariance
# 	HighGrayLevelRunEmphasis
# 	LongRunEmphasis
# 	LongRunHighGrayLevelEmphasis
# 	LongRunLowGrayLevelEmphasis
# 	LowGrayLevelRunEmphasis
# 	RunEntropy
# 	RunLengthNonUniformity
# 	RunLengthNonUniformityNormalized
# 	RunPercentage
# 	RunVariance
# 	ShortRunEmphasis
# 	ShortRunHighGrayLevelEmphasis
# 	ShortRunLowGrayLevelEmphasis
#
# Trained with weights
#
# Variable Importance: INV_MEAN_MIN_DEPTH:
#     1.     "LongRunHighGrayLevelEmphasis"  0.240751 ################
#     2.           "GrayLevelNonUniformity"  0.228847 #############
#     3.                       "RunEntropy"  0.217087 ##########
#     4. "RunLengthNonUniformityNormalized"  0.213786 #########
#     5.     "ShortRunLowGrayLevelEmphasis"  0.212253 #########
#     6.                      "RunVariance"  0.198327 ######
#     7.                "GrayLevelVariance"  0.192458 ####
#     8.      "LongRunLowGrayLevelEmphasis"  0.190743 ####
#     9.         "HighGrayLevelRunEmphasis"  0.189972 ####
#    10.    "ShortRunHighGrayLevelEmphasis"  0.189560 ###
#    11.                 "ShortRunEmphasis"  0.186407 ###
#    12.          "LowGrayLevelRunEmphasis"  0.185730 ###
#    13. "GrayLevelNonUniformityNormalized"  0.185584 ###
#    14.           "RunLengthNonUniformity"  0.182956 ##
#    15.                  "LongRunEmphasis"  0.179940 #
#    16.                    "RunPercentage"  0.172804
#
# Variable Importance: NUM_AS_ROOT:
#     1.     "LongRunHighGrayLevelEmphasis" 38.000000 ################
#     2.           "GrayLevelNonUniformity" 33.000000 #############
#     3.     "ShortRunLowGrayLevelEmphasis" 28.000000 ###########
#     4. "RunLengthNonUniformityNormalized" 23.000000 #########
#     5.         "HighGrayLevelRunEmphasis" 11.000000 ####
#     6.          "LowGrayLevelRunEmphasis" 11.000000 ####
#     7.                      "RunVariance" 11.000000 ####
#     8.                       "RunEntropy" 10.000000 ###
#     9.           "RunLengthNonUniformity" 10.000000 ###
#    10.      "LongRunLowGrayLevelEmphasis"  9.000000 ###
#    11.                 "ShortRunEmphasis"  6.000000 #
#    12.    "ShortRunHighGrayLevelEmphasis"  3.000000
#    13.                "GrayLevelVariance"  2.000000
#
# Variable Importance: NUM_NODES:
#     1.     "LongRunHighGrayLevelEmphasis" 737.000000 ################
#     2.                       "RunEntropy" 564.000000 ###########
#     3.           "GrayLevelNonUniformity" 520.000000 ##########
#     4.                "GrayLevelVariance" 433.000000 ########
#     5.     "ShortRunLowGrayLevelEmphasis" 426.000000 ########
#     6.    "ShortRunHighGrayLevelEmphasis" 356.000000 ######
#     7.      "LongRunLowGrayLevelEmphasis" 316.000000 #####
#     8. "RunLengthNonUniformityNormalized" 302.000000 #####
#     9.                      "RunVariance" 297.000000 ####
#    10.         "HighGrayLevelRunEmphasis" 289.000000 ####
#    11. "GrayLevelNonUniformityNormalized" 251.000000 ###
#    12.          "LowGrayLevelRunEmphasis" 247.000000 ###
#    13.                 "ShortRunEmphasis" 200.000000 ##
#    14.                  "LongRunEmphasis" 172.000000 #
#    15.           "RunLengthNonUniformity" 149.000000 #
#    16.                    "RunPercentage" 101.000000
#
# Variable Importance: SUM_SCORE:
#     1.         "HighGrayLevelRunEmphasis" 44681.329496 ################
#     2.     "LongRunHighGrayLevelEmphasis" 39963.419638 ##############
#     3.     "ShortRunLowGrayLevelEmphasis" 36926.113787 #############
#     4.    "ShortRunHighGrayLevelEmphasis" 23236.087880 ########
#     5.                       "RunEntropy" 20476.524643 #######
#     6.           "GrayLevelNonUniformity" 11291.466979 ###
#     7.      "LongRunLowGrayLevelEmphasis" 6540.385493 ##
#     8.                "GrayLevelVariance" 5071.589308 #
#     9.          "LowGrayLevelRunEmphasis" 4357.909442 #
#    10.                      "RunVariance" 4147.568244 #
#    11. "RunLengthNonUniformityNormalized" 2595.607922
#    12.                 "ShortRunEmphasis" 2161.739016
#    13. "GrayLevelNonUniformityNormalized" 1374.078943
#    14.                  "LongRunEmphasis" 961.702960
#    15.           "RunLengthNonUniformity" 888.802823
#    16.                    "RunPercentage" 518.719935
#
#
#
# Loss: BINOMIAL_LOG_LIKELIHOOD
# Validation loss value: 0.567228
# Number of trees per iteration: 1
# Node format: NOT_SET
# Number of trees: 195
# Total number of nodes: 10915
#
# Number of nodes by tree:
# Count: 195 Average: 55.9744 StdDev: 7.28147
# Min: 31 Max: 63 Ignored: 0
# ----------------------------------------------
# [ 31, 32)  2   1.03%   1.03%
# [ 32, 34)  0   0.00%   1.03%
# [ 34, 35)  0   0.00%   1.03%
# [ 35, 37)  1   0.51%   1.54%
# [ 37, 39)  0   0.00%   1.54%
# [ 39, 40)  2   1.03%   2.56%
# [ 40, 42)  6   3.08%   5.64% #
# [ 42, 44)  4   2.05%   7.69% #
# [ 44, 45)  0   0.00%   7.69%
# [ 45, 47)  7   3.59%  11.28% #
# [ 47, 49)  8   4.10%  15.38% #
# [ 49, 50) 14   7.18%  22.56% ##
# [ 50, 52) 12   6.15%  28.72% ##
# [ 52, 54)  5   2.56%  31.28% #
# [ 54, 55)  0   0.00%  31.28%
# [ 55, 57) 17   8.72%  40.00% ###
# [ 57, 59) 19   9.74%  49.74% ###
# [ 59, 60) 21  10.77%  60.51% ####
# [ 60, 62) 20  10.26%  70.77% ####
# [ 62, 63] 57  29.23% 100.00% ##########
#
# Depth by leafs:
# Count: 5555 Average: 4.91017 StdDev: 0.370898
# Min: 1 Max: 5 Ignored: 0
# ----------------------------------------------
# [ 1, 2)    2   0.04%   0.04%
# [ 2, 3)   21   0.38%   0.41%
# [ 3, 4)   80   1.44%   1.85%
# [ 4, 5)  268   4.82%   6.68% #
# [ 5, 5] 5184  93.32% 100.00% ##########
#
# Number of training obs by leaf:
# Count: 5555 Average: 7443.14 StdDev: 24402.6
# Min: 5 Max: 207907 Ignored: 0
# ----------------------------------------------
# [      5,  10400) 4855  87.40%  87.40% ##########
# [  10400,  20795)  279   5.02%  92.42% #
# [  20795,  31190)  110   1.98%  94.40%
# [  31190,  41585)   63   1.13%  95.54%
# [  41585,  51980)   48   0.86%  96.40%
# [  51980,  62375)   24   0.43%  96.83%
# [  62375,  72771)   21   0.38%  97.21%
# [  72771,  83166)   16   0.29%  97.50%
# [  83166,  93561)   16   0.29%  97.79%
# [  93561, 103956)   12   0.22%  98.00%
# [ 103956, 114351)    9   0.16%  98.16%
# [ 114351, 124746)    6   0.11%  98.27%
# [ 124746, 135141)   15   0.27%  98.54%
# [ 135141, 145537)   15   0.27%  98.81%
# [ 145537, 155932)    9   0.16%  98.97%
# [ 155932, 166327)   14   0.25%  99.23%
# [ 166327, 176722)   13   0.23%  99.46%
# [ 176722, 187117)   16   0.29%  99.75%
# [ 187117, 197512)   10   0.18%  99.93%
# [ 197512, 207907]    4   0.07% 100.00%
#
# Attribute in nodes:
# 	737 : LongRunHighGrayLevelEmphasis [NUMERICAL]
# 	564 : RunEntropy [NUMERICAL]
# 	520 : GrayLevelNonUniformity [NUMERICAL]
# 	433 : GrayLevelVariance [NUMERICAL]
# 	426 : ShortRunLowGrayLevelEmphasis [NUMERICAL]
# 	356 : ShortRunHighGrayLevelEmphasis [NUMERICAL]
# 	316 : LongRunLowGrayLevelEmphasis [NUMERICAL]
# 	302 : RunLengthNonUniformityNormalized [NUMERICAL]
# 	297 : RunVariance [NUMERICAL]
# 	289 : HighGrayLevelRunEmphasis [NUMERICAL]
# 	251 : GrayLevelNonUniformityNormalized [NUMERICAL]
# 	247 : LowGrayLevelRunEmphasis [NUMERICAL]
# 	200 : ShortRunEmphasis [NUMERICAL]
# 	172 : LongRunEmphasis [NUMERICAL]
# 	149 : RunLengthNonUniformity [NUMERICAL]
# 	101 : RunPercentage [NUMERICAL]
#
# Attribute in nodes with depth <= 0:
# 	38 : LongRunHighGrayLevelEmphasis [NUMERICAL]
# 	33 : GrayLevelNonUniformity [NUMERICAL]
# 	28 : ShortRunLowGrayLevelEmphasis [NUMERICAL]
# 	23 : RunLengthNonUniformityNormalized [NUMERICAL]
# 	11 : RunVariance [NUMERICAL]
# 	11 : LowGrayLevelRunEmphasis [NUMERICAL]
# 	11 : HighGrayLevelRunEmphasis [NUMERICAL]
# 	10 : RunLengthNonUniformity [NUMERICAL]
# 	10 : RunEntropy [NUMERICAL]
# 	9 : LongRunLowGrayLevelEmphasis [NUMERICAL]
# 	6 : ShortRunEmphasis [NUMERICAL]
# 	3 : ShortRunHighGrayLevelEmphasis [NUMERICAL]
# 	2 : GrayLevelVariance [NUMERICAL]
#
# Attribute in nodes with depth <= 1:
# 	72 : RunLengthNonUniformityNormalized [NUMERICAL]
# 	71 : RunEntropy [NUMERICAL]
# 	71 : LongRunHighGrayLevelEmphasis [NUMERICAL]
# 	62 : GrayLevelNonUniformity [NUMERICAL]
# 	56 : RunVariance [NUMERICAL]
# 	45 : ShortRunLowGrayLevelEmphasis [NUMERICAL]
# 	30 : LongRunLowGrayLevelEmphasis [NUMERICAL]
# 	28 : ShortRunEmphasis [NUMERICAL]
# 	26 : GrayLevelVariance [NUMERICAL]
# 	25 : ShortRunHighGrayLevelEmphasis [NUMERICAL]
# 	24 : HighGrayLevelRunEmphasis [NUMERICAL]
# 	24 : GrayLevelNonUniformityNormalized [NUMERICAL]
# 	18 : LongRunEmphasis [NUMERICAL]
# 	17 : RunLengthNonUniformity [NUMERICAL]
# 	14 : LowGrayLevelRunEmphasis [NUMERICAL]
#
# Attribute in nodes with depth <= 2:
# 	172 : LongRunHighGrayLevelEmphasis [NUMERICAL]
# 	156 : RunEntropy [NUMERICAL]
# 	139 : GrayLevelNonUniformity [NUMERICAL]
# 	112 : RunLengthNonUniformityNormalized [NUMERICAL]
# 	103 : RunVariance [NUMERICAL]
# 	98 : ShortRunLowGrayLevelEmphasis [NUMERICAL]
# 	84 : GrayLevelVariance [NUMERICAL]
# 	80 : LongRunLowGrayLevelEmphasis [NUMERICAL]
# 	77 : ShortRunHighGrayLevelEmphasis [NUMERICAL]
# 	68 : GrayLevelNonUniformityNormalized [NUMERICAL]
# 	57 : HighGrayLevelRunEmphasis [NUMERICAL]
# 	54 : ShortRunEmphasis [NUMERICAL]
# 	47 : LongRunEmphasis [NUMERICAL]
# 	41 : RunLengthNonUniformity [NUMERICAL]
# 	35 : LowGrayLevelRunEmphasis [NUMERICAL]
# 	15 : RunPercentage [NUMERICAL]
#
# Attribute in nodes with depth <= 3:
# 	374 : LongRunHighGrayLevelEmphasis [NUMERICAL]
# 	290 : RunEntropy [NUMERICAL]
# 	287 : GrayLevelNonUniformity [NUMERICAL]
# 	219 : GrayLevelVariance [NUMERICAL]
# 	203 : ShortRunLowGrayLevelEmphasis [NUMERICAL]
# 	201 : RunLengthNonUniformityNormalized [NUMERICAL]
# 	174 : ShortRunHighGrayLevelEmphasis [NUMERICAL]
# 	171 : RunVariance [NUMERICAL]
# 	161 : LongRunLowGrayLevelEmphasis [NUMERICAL]
# 	133 : HighGrayLevelRunEmphasis [NUMERICAL]
# 	133 : GrayLevelNonUniformityNormalized [NUMERICAL]
# 	106 : LowGrayLevelRunEmphasis [NUMERICAL]
# 	100 : ShortRunEmphasis [NUMERICAL]
# 	91 : LongRunEmphasis [NUMERICAL]
# 	83 : RunLengthNonUniformity [NUMERICAL]
# 	42 : RunPercentage [NUMERICAL]
#
# Attribute in nodes with depth <= 5:
# 	737 : LongRunHighGrayLevelEmphasis [NUMERICAL]
# 	564 : RunEntropy [NUMERICAL]
# 	520 : GrayLevelNonUniformity [NUMERICAL]
# 	433 : GrayLevelVariance [NUMERICAL]
# 	426 : ShortRunLowGrayLevelEmphasis [NUMERICAL]
# 	356 : ShortRunHighGrayLevelEmphasis [NUMERICAL]
# 	316 : LongRunLowGrayLevelEmphasis [NUMERICAL]
# 	302 : RunLengthNonUniformityNormalized [NUMERICAL]
# 	297 : RunVariance [NUMERICAL]
# 	289 : HighGrayLevelRunEmphasis [NUMERICAL]
# 	251 : GrayLevelNonUniformityNormalized [NUMERICAL]
# 	247 : LowGrayLevelRunEmphasis [NUMERICAL]
# 	200 : ShortRunEmphasis [NUMERICAL]
# 	172 : LongRunEmphasis [NUMERICAL]
# 	149 : RunLengthNonUniformity [NUMERICAL]
# 	101 : RunPercentage [NUMERICAL]
#
# Condition type in nodes:
# 	5360 : HigherCondition
# Condition type in nodes with depth <= 0:
# 	195 : HigherCondition
# Condition type in nodes with depth <= 1:
# 	583 : HigherCondition
# Condition type in nodes with depth <= 2:
# 	1338 : HigherCondition
# Condition type in nodes with depth <= 3:
# 	2768 : HigherCondition
# Condition type in nodes with depth <= 5:
# 	5360 : HigherCondition
#
# Training logs:
# Number of iteration to final model: 195
# 	Iter:1 train-loss:1.285084 valid-loss:1.288035  train-accuracy:0.832182 valid-accuracy:0.821345
# 	Iter:2 train-loss:1.200589 valid-loss:1.205359  train-accuracy:0.841044 valid-accuracy:0.832077
# 	Iter:3 train-loss:1.129699 valid-loss:1.136419  train-accuracy:0.844328 valid-accuracy:0.834962
# 	Iter:4 train-loss:1.069134 valid-loss:1.078060  train-accuracy:0.845753 valid-accuracy:0.837237
# 	Iter:5 train-loss:1.012135 valid-loss:1.022921  train-accuracy:0.855054 valid-accuracy:0.847071
# 	Iter:6 train-loss:0.963630 valid-loss:0.976009  train-accuracy:0.857597 valid-accuracy:0.849280
# 	Iter:16 train-loss:0.717349 valid-loss:0.744412  train-accuracy:0.866226 valid-accuracy:0.855645
# 	Iter:26 train-loss:0.632740 valid-loss:0.671042  train-accuracy:0.876377 valid-accuracy:0.859229
# 	Iter:36 train-loss:0.589219 valid-loss:0.634367  train-accuracy:0.882044 valid-accuracy:0.864283
# 	Iter:46 train-loss:0.563115 valid-loss:0.614407  train-accuracy:0.885799 valid-accuracy:0.868616
# 	Iter:56 train-loss:0.545201 valid-loss:0.602489  train-accuracy:0.888728 valid-accuracy:0.871298
# 	Iter:66 train-loss:0.532040 valid-loss:0.594173  train-accuracy:0.891060 valid-accuracy:0.870178
# 	Iter:76 train-loss:0.521351 valid-loss:0.587766  train-accuracy:0.893236 valid-accuracy:0.871633
# 	Iter:86 train-loss:0.512363 valid-loss:0.583972  train-accuracy:0.895148 valid-accuracy:0.873871
# 	Iter:96 train-loss:0.502908 valid-loss:0.579638  train-accuracy:0.897119 valid-accuracy:0.873800
# 	Iter:106 train-loss:0.495380 valid-loss:0.576805  train-accuracy:0.898869 valid-accuracy:0.874557
# 	Iter:116 train-loss:0.488544 valid-loss:0.574356  train-accuracy:0.900647 valid-accuracy:0.875002
# 	Iter:126 train-loss:0.482108 valid-loss:0.572712  train-accuracy:0.901965 valid-accuracy:0.875803
# 	Iter:136 train-loss:0.477357 valid-loss:0.571452  train-accuracy:0.902959 valid-accuracy:0.876181
# 	Iter:146 train-loss:0.471751 valid-loss:0.571204  train-accuracy:0.904217 valid-accuracy:0.876439
# 	Iter:156 train-loss:0.466818 valid-loss:0.570211  train-accuracy:0.905282 valid-accuracy:0.877138
# 	Iter:166 train-loss:0.462349 valid-loss:0.569200  train-accuracy:0.906488 valid-accuracy:0.877196
# 	Iter:176 train-loss:0.458034 valid-loss:0.568634  train-accuracy:0.907866 valid-accuracy:0.876889
# 	Iter:186 train-loss:0.453692 valid-loss:0.567950  train-accuracy:0.908686 valid-accuracy:0.877014
# 	Iter:196 train-loss:0.450333 valid-loss:0.567459  train-accuracy:0.909706 valid-accuracy:0.877579
# 	Iter:206 train-loss:0.446975 valid-loss:0.567290  train-accuracy:0.911135 valid-accuracy:0.877815
# 	Iter:216 train-loss:0.443097 valid-loss:0.568061  train-accuracy:0.912441 valid-accuracy:0.877718

# %%
# Model features
model.make_inspector().features()
# Out:
# ["GrayLevelNonUniformity" (1; #0),
#  "GrayLevelNonUniformityNormalized" (1; #1),
#  "GrayLevelVariance" (1; #2),
#  "HighGrayLevelRunEmphasis" (1; #3),
#  "LongRunEmphasis" (1; #4),
#  "LongRunHighGrayLevelEmphasis" (1; #5),
#  "LongRunLowGrayLevelEmphasis" (1; #6),
#  "LowGrayLevelRunEmphasis" (1; #7),
#  "RunEntropy" (1; #8),
#  "RunLengthNonUniformity" (1; #9),
#  "RunLengthNonUniformityNormalized" (1; #10),
#  "RunPercentage" (1; #11),
#  "RunVariance" (1; #12),
#  "ShortRunEmphasis" (1; #13),
#  "ShortRunHighGrayLevelEmphasis" (1; #14),
#  "ShortRunLowGrayLevelEmphasis" (1; #15)]

# %%
# Feature importance
model.make_inspector().variable_importances()
# Out:
# {'INV_MEAN_MIN_DEPTH': [("LongRunHighGrayLevelEmphasis" (1; #5),
#    0.24075083041711046),
#   ("GrayLevelNonUniformity" (1; #0), 0.2288467162103668),
#   ("RunEntropy" (1; #8), 0.21708746436508358),
#   ("RunLengthNonUniformityNormalized" (1; #10), 0.213786394939825),
#   ("ShortRunLowGrayLevelEmphasis" (1; #15), 0.21225298720442873),
#   ("RunVariance" (1; #12), 0.1983267900239929),
#   ("GrayLevelVariance" (1; #2), 0.19245817011599062),
#   ("LongRunLowGrayLevelEmphasis" (1; #6), 0.19074257200904277),
#   ("HighGrayLevelRunEmphasis" (1; #3), 0.18997177747449595),
#   ("ShortRunHighGrayLevelEmphasis" (1; #14), 0.18956036751206704),
#   ("ShortRunEmphasis" (1; #13), 0.18640721737957816),
#   ("LowGrayLevelRunEmphasis" (1; #7), 0.1857303898387361),
#   ("GrayLevelNonUniformityNormalized" (1; #1), 0.18558402391522602),
#   ("RunLengthNonUniformity" (1; #9), 0.18295574163649406),
#   ("LongRunEmphasis" (1; #4), 0.17994008092140407),
#   ("RunPercentage" (1; #11), 0.1728044546930952)],
#  'SUM_SCORE': [("HighGrayLevelRunEmphasis" (1; #3), 44681.329495532686),
#   ("LongRunHighGrayLevelEmphasis" (1; #5), 39963.41963826084),
#   ("ShortRunLowGrayLevelEmphasis" (1; #15), 36926.11378718241),
#   ("ShortRunHighGrayLevelEmphasis" (1; #14), 23236.08787958227),
#   ("RunEntropy" (1; #8), 20476.52464277631),
#   ("GrayLevelNonUniformity" (1; #0), 11291.466979083081),
#   ("LongRunLowGrayLevelEmphasis" (1; #6), 6540.385492530855),
#   ("GrayLevelVariance" (1; #2), 5071.5893076782795),
#   ("LowGrayLevelRunEmphasis" (1; #7), 4357.909441738729),
#   ("RunVariance" (1; #12), 4147.568243509004),
#   ("RunLengthNonUniformityNormalized" (1; #10), 2595.6079219262247),
#   ("ShortRunEmphasis" (1; #13), 2161.739015850003),
#   ("GrayLevelNonUniformityNormalized" (1; #1), 1374.0789427210725),
#   ("LongRunEmphasis" (1; #4), 961.7029596013108),
#   ("RunLengthNonUniformity" (1; #9), 888.802823108929),
#   ("RunPercentage" (1; #11), 518.7199348101916)],
#  'NUM_AS_ROOT': [("LongRunHighGrayLevelEmphasis" (1; #5), 38.0),
#   ("GrayLevelNonUniformity" (1; #0), 33.0),
#   ("ShortRunLowGrayLevelEmphasis" (1; #15), 28.0),
#   ("RunLengthNonUniformityNormalized" (1; #10), 23.0),
#   ("HighGrayLevelRunEmphasis" (1; #3), 11.0),
#   ("LowGrayLevelRunEmphasis" (1; #7), 11.0),
#   ("RunVariance" (1; #12), 11.0),
#   ("RunEntropy" (1; #8), 10.0),
#   ("RunLengthNonUniformity" (1; #9), 10.0),
#   ("LongRunLowGrayLevelEmphasis" (1; #6), 9.0),
#   ("ShortRunEmphasis" (1; #13), 6.0),
#   ("ShortRunHighGrayLevelEmphasis" (1; #14), 3.0),
#   ("GrayLevelVariance" (1; #2), 2.0)],
#  'NUM_NODES': [("LongRunHighGrayLevelEmphasis" (1; #5), 737.0),
#   ("RunEntropy" (1; #8), 564.0),
#   ("GrayLevelNonUniformity" (1; #0), 520.0),
#   ("GrayLevelVariance" (1; #2), 433.0),
#   ("ShortRunLowGrayLevelEmphasis" (1; #15), 426.0),
#   ("ShortRunHighGrayLevelEmphasis" (1; #14), 356.0),
#   ("LongRunLowGrayLevelEmphasis" (1; #6), 316.0),
#   ("RunLengthNonUniformityNormalized" (1; #10), 302.0),
#   ("RunVariance" (1; #12), 297.0),
#   ("HighGrayLevelRunEmphasis" (1; #3), 289.0),
#   ("GrayLevelNonUniformityNormalized" (1; #1), 251.0),
#   ("LowGrayLevelRunEmphasis" (1; #7), 247.0),
#   ("ShortRunEmphasis" (1; #13), 200.0),
#   ("LongRunEmphasis" (1; #4), 172.0),
#   ("RunLengthNonUniformity" (1; #9), 149.0),
#   ("RunPercentage" (1; #11), 101.0)]}

# %%
# Model self evaluation
model.make_inspector().evaluation()
# Out:
# Evaluation(num_examples=None, accuracy=0.8775792717933655, loss=0.5672283172607422, rmse=None, ndcg=None, aucs=None, auuc=None, qini=None)

# %%
logs = model.make_inspector().training_logs()

plt.figure(figsize=(12, 4))
plt.subplot(1, 2, 1)
plt.plot([log.num_trees for log in logs], [log.evaluation.accuracy for log in logs])
plt.xlabel("Number of trees")
plt.ylabel("Accuracy (out-of-bag)")
plt.subplot(1, 2, 2)
plt.plot([log.num_trees for log in logs], [log.evaluation.loss for log in logs])
plt.xlabel("Number of trees")
plt.ylabel("Logloss (out-of-bag)")
plt.show()

# %% [markdown]
# Calculate the score of our hold-out validation dataset

# %%
predictions = model.predict(val_ds)
y_true      = validation_data["label"]

from sklearn.metrics import roc_auc_score
ROC_AUC = roc_auc_score(y_true, predictions)
print("The ROC AUC score is %.5f" % ROC_AUC )
# Out:
#  1/34 [..............................] - ETA: 2s
# 13/34 [==========>...................] - ETA: 0s
# 26/34 [=====================>........] - ETA: 0s
# 34/34 [==============================] - 0s 4ms/step
# The ROC AUC score is 0.95528

# %%
# Compute binary classification metrics with sklearn
import numpy as np
from sklearn.metrics import (
    accuracy_score,
    precision_score,
    recall_score,
    f1_score,
    roc_auc_score,
    average_precision_score,
    confusion_matrix,
    classification_report,
    matthews_corrcoef,
    log_loss,
    brier_score_loss,
)

# Get predictions (probabilities or class labels)
preds = model.predict(test_ds)
# If model outputs probabilities, convert to labels by threshold 0.5
if preds.ndim == 2:
    # For TFDF classification, preds may be class probabilities with shape (N, 2)
    if preds.shape[1] == 2:
        pos_probs = preds[:, 1]
    else:
        # If single-probability column (positive class)
        pos_probs = preds[:, -1]
    y_pred = (pos_probs >= 0.5).astype(int)
else:
    # Already class labels
    y_pred = preds.astype(int)
    pos_probs = None

# Ground truth labels (must be 0/1 integers)
y_true = test_data["label"].astype(int).to_numpy()

# Core metrics
metrics = {}
metrics["accuracy"] = accuracy_score(y_true, y_pred)
metrics["precision"] = precision_score(y_true, y_pred, zero_division=0)
metrics["recall"] = recall_score(y_true, y_pred, zero_division=0)
metrics["f1"] = f1_score(y_true, y_pred, zero_division=0)
metrics["mcc"] = matthews_corrcoef(y_true, y_pred)

# Probabilistic metrics (only if we have probabilities)
if pos_probs is not None:
    metrics["roc_auc"] = roc_auc_score(y_true, pos_probs)
    metrics["pr_auc"] = average_precision_score(y_true, pos_probs)
    metrics["log_loss"] = log_loss(y_true, pos_probs, labels=[0,1])
    metrics["brier_score"] = brier_score_loss(y_true, pos_probs)

# Confusion matrix and detailed report
cm = confusion_matrix(y_true, y_pred, labels=[0,1])
report = classification_report(y_true, y_pred, digits=4)

print("Sklearn binary metrics:")
for k, v in metrics.items():
    print(f"{k}: {v:.4f}")
print("\nConfusion matrix:\n", cm)
print("\nClassification report:\n", report)
# Out:
#  1/68 [..............................] - ETA: 4s
# 13/68 [====>.........................] - ETA: 0s
# 26/68 [==========>...................] - ETA: 0s
# 38/68 [===============>..............] - ETA: 0s
# 50/68 [=====================>........] - ETA: 0s
# 62/68 [==========================>...] - ETA: 0s
# 68/68 [==============================] - 0s 4ms/step
# Sklearn binary metrics:
# accuracy: 0.8943
# precision: 0.3488
# recall: 0.8623
# f1: 0.4967
# mcc: 0.5072
# roc_auc: 0.9536
# pr_auc: 0.6901
# log_loss: 0.2511
# brier_score: 0.0768
#
# Confusion matrix:
#  [[56717  6556]
#  [  561  3512]]
#
# Classification report:
#                precision    recall  f1-score   support
#
#            0     0.9902    0.8964    0.9410     63273
#            1     0.3488    0.8623    0.4967      4073
#
#     accuracy                         0.8943     67346
#    macro avg     0.6695    0.8793    0.7188     67346
# weighted avg     0.9514    0.8943    0.9141     67346
