# %%
# Import packages and modules
import numpy  as np
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow_decision_forests as tfdf

from sklearn.model_selection import train_test_split
# Out:
# 2026-07-04 08:22:06.174590: I tensorflow/core/util/port.cc:113] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2026-07-04 08:22:06.214548: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2026-07-04 08:22:10.499549: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
# Check the version of TensorFlow Decision Forests
print("Found TensorFlow Decision Forests v" + tfdf.__version__)
# Out:
# Found TensorFlow Decision Forests v1.9.1

# %%
datasetPath = 'dataset/firstorder/kernel5-radius5/dataset.csv'

# %%
# Parameters
datasetPath = "dataset/glcm/kernel5-radius5/400.dataset.csv"

# %%
# train/validation/test = 70/10/20
dataset = pd.read_csv(datasetPath)

train_data, temp_data = train_test_split(dataset, test_size=0.3, random_state=42)
validation_data, test_data = train_test_split(temp_data, test_size=2/3, random_state=42)

# %%
from sklearn.utils.class_weight import compute_class_weight

# tinh class weight tren tap train
classes = np.array([0, 1])
weights = compute_class_weight(class_weight="balanced", classes=classes, y=train_data["label"])
class_weight = {0: weights[0], 1: weights[1]}

# gan sample_weight cho tung dong
train_data["sample_weight"] = train_data["label"].map(class_weight)
validation_data["sample_weight"] = validation_data["label"].map(class_weight)
test_data["sample_weight"] = test_data["label"].map(class_weight)

# Convert the dataset into a TensorFlow dataset.
train_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    train_data, label="label", weight="sample_weight"
)         
val_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    validation_data, label="label", weight="sample_weight"
)
test_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    test_data, label="label", weight="sample_weight"
)
# Out:
# 2026-07-04 08:22:24.902274: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:984] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2026-07-04 08:22:24.903906: W tensorflow/core/common_runtime/gpu/gpu_device.cc:2251] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...

# %%
import keras

# %%
# %%time

# Train a Gradient Boosted Trees model.
model = tfdf.keras.GradientBoostedTreesModel()

# Add evaluation metrics
model.compile(
    metrics=["accuracy"]
)
model.fit(x=train_ds)

# # Train a Gradient Boosted Trees model.
# model = tfdf.keras.GradientBoostedTreesModel(num_trees=1500)
# model.fit(train_ds)
# Out:
# Use /tmp/tmp67hnoaja as temporary training directory
# Reading training dataset...
# [WARNING 26-07-04 08:22:25.1899 UTC gradient_boosted_trees.cc:1840] "goss_alpha" set but "sampling_method" not equal to "GOSS".
# [WARNING 26-07-04 08:22:25.1901 UTC gradient_boosted_trees.cc:1851] "goss_beta" set but "sampling_method" not equal to "GOSS".
# [WARNING 26-07-04 08:22:25.1901 UTC gradient_boosted_trees.cc:1865] "selective_gradient_boosting_ratio" set but "sampling_method" not equal to "SELGB".
# Training dataset read in 0:00:04.308481. Found 315417 examples.
# Training model...
# Model trained in 0:01:37.600407
# Compiling model...
# [INFO 26-07-04 08:24:07.1123 UTC kernel.cc:1233] Loading model from path /tmp/tmp67hnoaja/model/ with prefix f991692ed93641ae
# [INFO 26-07-04 08:24:07.1277 UTC quick_scorer_extended.cc:911] The binary was compiled without AVX2 support, but your CPU supports it. Enable it for faster model inference.
# [INFO 26-07-04 08:24:07.1292 UTC abstract_model.cc:1362] Engine "GradientBoostedTreesQuickScorerExtended" built
# [INFO 26-07-04 08:24:07.1292 UTC kernel.cc:1061] Use fast generic engine
# Model compiled.
# CPU times: user 16min, sys: 6.02 s, total: 16min 6s
# Wall time: 1min 45s

# %%
# Evaluate the model
evaluate = model.evaluate(val_ds, return_dict=True)
print()

for name, value in evaluate.items():
    print(f"{name}: {value:.4f}")
# Out:
# WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
#  1/46 [..............................] - ETA: 2:12 - loss: 0.0000e+00 - accuracy: 0.9320
# 10/46 [=====>........................] - ETA: 0s - loss: 0.0000e+00 - accuracy: 0.9270
# 19/46 [===========>..................] - ETA: 0s - loss: 0.0000e+00 - accuracy: 0.9286
# 28/46 [=================>............] - ETA: 0s - loss: 0.0000e+00 - accuracy: 0.9273
# 38/46 [=======================>......] - ETA: 0s - loss: 0.0000e+00 - accuracy: 0.9280
# 46/46 [==============================] - 3s 6ms/step - loss: 0.0000e+00 - accuracy: 0.9280
# loss: 0.0000
# accuracy: 0.9280

# %%
# Model Summary
model.summary()
# Out:
# Model: "gradient_boosted_trees_model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
# =================================================================
# Total params: 1 (1.00 Byte)
# Trainable params: 0 (0.00 Byte)
# Non-trainable params: 1 (1.00 Byte)
# _________________________________________________________________
# Type: "GRADIENT_BOOSTED_TREES"
# Task: CLASSIFICATION
# Label: "__LABEL"
#
# Input Features (24):
# 	Autocorrelation
# 	ClusterProminence
# 	ClusterShade
# 	ClusterTendency
# 	Contrast
# 	Correlation
# 	DifferenceAverage
# 	DifferenceEntropy
# 	DifferenceVariance
# 	Id
# 	Idm
# 	Idmn
# 	Idn
# 	Imc1
# 	Imc2
# 	InverseVariance
# 	JointAverage
# 	JointEnergy
# 	JointEntropy
# 	MCC
# 	MaximumProbability
# 	SumAverage
# 	SumEntropy
# 	SumSquares
#
# Trained with weights
#
# Variable Importance: INV_MEAN_MIN_DEPTH:
#     1.                "Idn"  0.244657 ################
#     2.               "Idmn"  0.243122 ###############
#     3.       "ClusterShade"  0.198079 #####
#     4.       "JointAverage"  0.197254 #####
#     5.    "Autocorrelation"  0.196351 #####
#     6.         "SumAverage"  0.195383 #####
#     7. "DifferenceVariance"  0.194009 ####
#     8.               "Imc1"  0.193764 ####
#     9.        "Correlation"  0.190977 ####
#    10.    "InverseVariance"  0.189380 ###
#    11.  "DifferenceEntropy"  0.184867 ##
#    12.  "DifferenceAverage"  0.183983 ##
#    13.               "Imc2"  0.181013 #
#    14. "MaximumProbability"  0.180819 #
#    15.           "Contrast"  0.179967 #
#    16.                "MCC"  0.176949 #
#    17.         "SumEntropy"  0.176905 #
#    18.  "ClusterProminence"  0.175687
#    19.         "SumSquares"  0.174958
#    20.                "Idm"  0.174892
#    21.    "ClusterTendency"  0.174678
#    22.                 "Id"  0.174506
#    23.        "JointEnergy"  0.172201
#    24.       "JointEntropy"  0.171959
#
# Variable Importance: NUM_AS_ROOT:
#     1.               "Idmn" 82.000000 ################
#     2.                "Idn" 78.000000 ###############
#     3.         "SumAverage" 21.000000 ###
#     4.               "Imc1" 20.000000 ###
#     5.       "JointAverage" 20.000000 ###
#     6.        "Correlation" 19.000000 ###
#     7.    "Autocorrelation" 10.000000 #
#     8.  "DifferenceAverage"  7.000000 #
#     9.    "InverseVariance"  7.000000 #
#    10.               "Imc2"  6.000000
#    11. "DifferenceVariance"  5.000000
#    12.       "ClusterShade"  3.000000
#    13.           "Contrast"  2.000000
#    14.                "MCC"  2.000000
#    15.  "DifferenceEntropy"  1.000000
#
# Variable Importance: NUM_NODES:
#     1.    "Autocorrelation" 675.000000 ################
#     2.       "ClusterShade" 662.000000 ###############
#     3.               "Idmn" 637.000000 ##############
#     4.                "Idn" 588.000000 #############
#     5.       "JointAverage" 499.000000 ###########
#     6.         "SumAverage" 456.000000 #########
#     7. "DifferenceVariance" 424.000000 #########
#     8.    "InverseVariance" 374.000000 #######
#     9.        "Correlation" 346.000000 ######
#    10. "MaximumProbability" 313.000000 #####
#    11.  "DifferenceEntropy" 304.000000 #####
#    12.               "Imc1" 300.000000 #####
#    13.               "Imc2" 278.000000 ####
#    14.                "MCC" 248.000000 ####
#    15.  "DifferenceAverage" 237.000000 ###
#    16.         "SumEntropy" 230.000000 ###
#    17.  "ClusterProminence" 208.000000 ##
#    18.           "Contrast" 197.000000 ##
#    19.                 "Id" 144.000000 #
#    20.         "SumSquares" 134.000000
#    21.    "ClusterTendency" 125.000000
#    22.        "JointEnergy" 125.000000
#    23.                "Idm" 118.000000
#    24.       "JointEntropy" 101.000000
#
# Variable Importance: SUM_SCORE:
#     1.    "Autocorrelation" 54520.738615 ################
#     2.         "SumAverage" 47468.483790 #############
#     3.        "Correlation" 47366.833825 #############
#     4.       "JointAverage" 39029.722201 ###########
#     5. "DifferenceVariance" 23982.275498 ######
#     6.                "Idn" 16592.158067 ####
#     7.    "InverseVariance" 11937.999112 ###
#     8.               "Idmn" 10619.878731 ###
#     9.               "Imc1" 10391.000982 ##
#    10.       "ClusterShade" 8599.603729 ##
#    11.  "DifferenceEntropy" 7270.574289 ##
#    12.  "DifferenceAverage" 6016.251433 #
#    13. "MaximumProbability" 4926.682423 #
#    14.           "Contrast" 2086.713336
#    15.               "Imc2" 1456.250142
#    16.         "SumEntropy" 1306.963410
#    17.                 "Id" 1281.808033
#    18.                "MCC" 883.442667
#    19.  "ClusterProminence" 820.844147
#    20.         "SumSquares" 742.900823
#    21.    "ClusterTendency" 629.342336
#    22.        "JointEnergy" 563.864375
#    23.                "Idm" 482.391631
#    24.       "JointEntropy" 453.728217
#
#
#
# Loss: BINOMIAL_LOG_LIKELIHOOD
# Validation loss value: 0.416885
# Number of trees per iteration: 1
# Node format: NOT_SET
# Number of trees: 283
# Total number of nodes: 15729
#
# Number of nodes by tree:
# Count: 283 Average: 55.5795 StdDev: 7.33667
# Min: 33 Max: 63 Ignored: 0
# ----------------------------------------------
# [ 33, 34)  1   0.35%   0.35%
# [ 34, 36)  0   0.00%   0.35%
# [ 36, 37)  0   0.00%   0.35%
# [ 37, 39)  5   1.77%   2.12% #
# [ 39, 40)  2   0.71%   2.83%
# [ 40, 42)  9   3.18%   6.01% #
# [ 42, 43)  0   0.00%   6.01%
# [ 43, 45)  8   2.83%   8.83% #
# [ 45, 46)  9   3.18%  12.01% #
# [ 46, 48) 15   5.30%  17.31% ##
# [ 48, 50) 23   8.13%  25.44% ###
# [ 50, 51)  0   0.00%  25.44%
# [ 51, 53) 15   5.30%  30.74% ##
# [ 53, 54) 17   6.01%  36.75% ##
# [ 54, 56) 24   8.48%  45.23% ###
# [ 56, 57)  0   0.00%  45.23%
# [ 57, 59) 21   7.42%  52.65% ###
# [ 59, 60) 16   5.65%  58.30% ##
# [ 60, 62) 39  13.78%  72.08% #####
# [ 62, 63] 79  27.92% 100.00% ##########
#
# Depth by leafs:
# Count: 8006 Average: 4.90819 StdDev: 0.387721
# Min: 2 Max: 5 Ignored: 0
# ----------------------------------------------
# [ 2, 3)   47   0.59%   0.59%
# [ 3, 4)  127   1.59%   2.17%
# [ 4, 5)  340   4.25%   6.42%
# [ 5, 5] 7492  93.58% 100.00% ##########
#
# Number of training obs by leaf:
# Count: 8006 Average: 10030.9 StdDev: 30491.1
# Min: 5 Max: 278575 Ignored: 0
# ----------------------------------------------
# [      5,  13933) 6867  85.77%  85.77% ##########
# [  13933,  27862)  473   5.91%  91.68% #
# [  27862,  41790)  194   2.42%  94.10%
# [  41790,  55719)   98   1.22%  95.33%
# [  55719,  69647)   73   0.91%  96.24%
# [  69647,  83576)   50   0.62%  96.86%
# [  83576,  97504)   38   0.47%  97.34%
# [  97504, 111433)   38   0.47%  97.81%
# [ 111433, 125361)   26   0.32%  98.14%
# [ 125361, 139290)   13   0.16%  98.30%
# [ 139290, 153219)   16   0.20%  98.50%
# [ 153219, 167147)   10   0.12%  98.63%
# [ 167147, 181076)   20   0.25%  98.88%
# [ 181076, 195004)   19   0.24%  99.11%
# [ 195004, 208933)   15   0.19%  99.30%
# [ 208933, 222861)   17   0.21%  99.51%
# [ 222861, 236790)   16   0.20%  99.71%
# [ 236790, 250718)   12   0.15%  99.86%
# [ 250718, 264647)    5   0.06%  99.93%
# [ 264647, 278575]    6   0.07% 100.00%
#
# Attribute in nodes:
# 	675 : Autocorrelation [NUMERICAL]
# 	662 : ClusterShade [NUMERICAL]
# 	637 : Idmn [NUMERICAL]
# 	588 : Idn [NUMERICAL]
# 	499 : JointAverage [NUMERICAL]
# 	456 : SumAverage [NUMERICAL]
# 	424 : DifferenceVariance [NUMERICAL]
# 	374 : InverseVariance [NUMERICAL]
# 	346 : Correlation [NUMERICAL]
# 	313 : MaximumProbability [NUMERICAL]
# 	304 : DifferenceEntropy [NUMERICAL]
# 	300 : Imc1 [NUMERICAL]
# 	278 : Imc2 [NUMERICAL]
# 	248 : MCC [NUMERICAL]
# 	237 : DifferenceAverage [NUMERICAL]
# 	230 : SumEntropy [NUMERICAL]
# 	208 : ClusterProminence [NUMERICAL]
# 	197 : Contrast [NUMERICAL]
# 	144 : Id [NUMERICAL]
# 	134 : SumSquares [NUMERICAL]
# 	125 : JointEnergy [NUMERICAL]
# 	125 : ClusterTendency [NUMERICAL]
# 	118 : Idm [NUMERICAL]
# 	101 : JointEntropy [NUMERICAL]
#
# Attribute in nodes with depth <= 0:
# 	82 : Idmn [NUMERICAL]
# 	78 : Idn [NUMERICAL]
# 	21 : SumAverage [NUMERICAL]
# 	20 : JointAverage [NUMERICAL]
# 	20 : Imc1 [NUMERICAL]
# 	19 : Correlation [NUMERICAL]
# 	10 : Autocorrelation [NUMERICAL]
# 	7 : InverseVariance [NUMERICAL]
# 	7 : DifferenceAverage [NUMERICAL]
# 	6 : Imc2 [NUMERICAL]
# 	5 : DifferenceVariance [NUMERICAL]
# 	3 : ClusterShade [NUMERICAL]
# 	2 : MCC [NUMERICAL]
# 	2 : Contrast [NUMERICAL]
# 	1 : DifferenceEntropy [NUMERICAL]
#
# Attribute in nodes with depth <= 1:
# 	133 : Idmn [NUMERICAL]
# 	127 : Idn [NUMERICAL]
# 	64 : ClusterShade [NUMERICAL]
# 	56 : DifferenceVariance [NUMERICAL]
# 	55 : Imc1 [NUMERICAL]
# 	47 : Correlation [NUMERICAL]
# 	46 : InverseVariance [NUMERICAL]
# 	43 : JointAverage [NUMERICAL]
# 	40 : DifferenceEntropy [NUMERICAL]
# 	36 : DifferenceAverage [NUMERICAL]
# 	33 : SumAverage [NUMERICAL]
# 	27 : Autocorrelation [NUMERICAL]
# 	25 : MaximumProbability [NUMERICAL]
# 	24 : Contrast [NUMERICAL]
# 	21 : Imc2 [NUMERICAL]
# 	14 : ClusterTendency [NUMERICAL]
# 	11 : MCC [NUMERICAL]
# 	11 : Idm [NUMERICAL]
# 	9 : SumSquares [NUMERICAL]
# 	9 : Id [NUMERICAL]
# 	6 : ClusterProminence [NUMERICAL]
# 	5 : SumEntropy [NUMERICAL]
# 	4 : JointEntropy [NUMERICAL]
# 	3 : JointEnergy [NUMERICAL]
#
# Attribute in nodes with depth <= 2:
# 	201 : Idmn [NUMERICAL]
# 	192 : Idn [NUMERICAL]
# 	151 : Autocorrelation [NUMERICAL]
# 	147 : ClusterShade [NUMERICAL]
# 	128 : DifferenceVariance [NUMERICAL]
# 	121 : SumAverage [NUMERICAL]
# 	117 : JointAverage [NUMERICAL]
# 	109 : InverseVariance [NUMERICAL]
# 	87 : Correlation [NUMERICAL]
# 	85 : Imc1 [NUMERICAL]
# 	81 : DifferenceEntropy [NUMERICAL]
# 	68 : Imc2 [NUMERICAL]
# 	62 : MaximumProbability [NUMERICAL]
# 	60 : DifferenceAverage [NUMERICAL]
# 	58 : Contrast [NUMERICAL]
# 	55 : SumEntropy [NUMERICAL]
# 	39 : ClusterProminence [NUMERICAL]
# 	33 : SumSquares [NUMERICAL]
# 	33 : MCC [NUMERICAL]
# 	33 : Idm [NUMERICAL]
# 	30 : Id [NUMERICAL]
# 	24 : ClusterTendency [NUMERICAL]
# 	10 : JointEntropy [NUMERICAL]
# 	10 : JointEnergy [NUMERICAL]
#
# Attribute in nodes with depth <= 3:
# 	345 : Idmn [NUMERICAL]
# 	323 : Idn [NUMERICAL]
# 	321 : ClusterShade [NUMERICAL]
# 	306 : Autocorrelation [NUMERICAL]
# 	260 : JointAverage [NUMERICAL]
# 	244 : DifferenceVariance [NUMERICAL]
# 	235 : SumAverage [NUMERICAL]
# 	210 : InverseVariance [NUMERICAL]
# 	180 : DifferenceEntropy [NUMERICAL]
# 	172 : Imc1 [NUMERICAL]
# 	165 : Correlation [NUMERICAL]
# 	155 : MaximumProbability [NUMERICAL]
# 	148 : Imc2 [NUMERICAL]
# 	124 : DifferenceAverage [NUMERICAL]
# 	122 : SumEntropy [NUMERICAL]
# 	110 : Contrast [NUMERICAL]
# 	99 : MCC [NUMERICAL]
# 	99 : ClusterProminence [NUMERICAL]
# 	76 : SumSquares [NUMERICAL]
# 	71 : Id [NUMERICAL]
# 	66 : Idm [NUMERICAL]
# 	58 : ClusterTendency [NUMERICAL]
# 	54 : JointEnergy [NUMERICAL]
# 	34 : JointEntropy [NUMERICAL]
#
# Attribute in nodes with depth <= 5:
# 	675 : Autocorrelation [NUMERICAL]
# 	662 : ClusterShade [NUMERICAL]
# 	637 : Idmn [NUMERICAL]
# 	588 : Idn [NUMERICAL]
# 	499 : JointAverage [NUMERICAL]
# 	456 : SumAverage [NUMERICAL]
# 	424 : DifferenceVariance [NUMERICAL]
# 	374 : InverseVariance [NUMERICAL]
# 	346 : Correlation [NUMERICAL]
# 	313 : MaximumProbability [NUMERICAL]
# 	304 : DifferenceEntropy [NUMERICAL]
# 	300 : Imc1 [NUMERICAL]
# 	278 : Imc2 [NUMERICAL]
# 	248 : MCC [NUMERICAL]
# 	237 : DifferenceAverage [NUMERICAL]
# 	230 : SumEntropy [NUMERICAL]
# 	208 : ClusterProminence [NUMERICAL]
# 	197 : Contrast [NUMERICAL]
# 	144 : Id [NUMERICAL]
# 	134 : SumSquares [NUMERICAL]
# 	125 : JointEnergy [NUMERICAL]
# 	125 : ClusterTendency [NUMERICAL]
# 	118 : Idm [NUMERICAL]
# 	101 : JointEntropy [NUMERICAL]
#
# Condition type in nodes:
# 	7723 : HigherCondition
# Condition type in nodes with depth <= 0:
# 	283 : HigherCondition
# Condition type in nodes with depth <= 1:
# 	849 : HigherCondition
# Condition type in nodes with depth <= 2:
# 	1934 : HigherCondition
# Condition type in nodes with depth <= 3:
# 	3977 : HigherCondition
# Condition type in nodes with depth <= 5:
# 	7723 : HigherCondition
#
# Training logs:
# Number of iteration to final model: 283
# 	Iter:1 train-loss:1.288761 valid-loss:1.290539  train-accuracy:0.816371 valid-accuracy:0.804619
# 	Iter:2 train-loss:1.210698 valid-loss:1.212927  train-accuracy:0.823572 valid-accuracy:0.817101
# 	Iter:3 train-loss:1.142223 valid-loss:1.144368  train-accuracy:0.833160 valid-accuracy:0.828764
# 	Iter:4 train-loss:1.079847 valid-loss:1.082742  train-accuracy:0.843598 valid-accuracy:0.839706
# 	Iter:5 train-loss:1.026694 valid-loss:1.029392  train-accuracy:0.847409 valid-accuracy:0.848579
# 	Iter:6 train-loss:0.978635 valid-loss:0.981770  train-accuracy:0.851006 valid-accuracy:0.851831
# 	Iter:16 train-loss:0.710767 valid-loss:0.721054  train-accuracy:0.880463 valid-accuracy:0.877927
# 	Iter:26 train-loss:0.593011 valid-loss:0.608409  train-accuracy:0.893446 valid-accuracy:0.889083
# 	Iter:36 train-loss:0.526588 valid-loss:0.547722  train-accuracy:0.903454 valid-accuracy:0.900513
# 	Iter:46 train-loss:0.483485 valid-loss:0.508417  train-accuracy:0.910928 valid-accuracy:0.908663
# 	Iter:56 train-loss:0.455951 valid-loss:0.485843  train-accuracy:0.914874 valid-accuracy:0.910814
# 	Iter:66 train-loss:0.435291 valid-loss:0.468857  train-accuracy:0.918161 valid-accuracy:0.913782
# 	Iter:76 train-loss:0.420833 valid-loss:0.458913  train-accuracy:0.920911 valid-accuracy:0.914538
# 	Iter:86 train-loss:0.407678 valid-loss:0.450614  train-accuracy:0.922791 valid-accuracy:0.916207
# 	Iter:96 train-loss:0.398113 valid-loss:0.444124  train-accuracy:0.924391 valid-accuracy:0.916560
# 	Iter:106 train-loss:0.389295 valid-loss:0.439174  train-accuracy:0.925879 valid-accuracy:0.917241
# 	Iter:116 train-loss:0.381836 valid-loss:0.435217  train-accuracy:0.927303 valid-accuracy:0.917640
# 	Iter:126 train-loss:0.376288 valid-loss:0.432919  train-accuracy:0.928114 valid-accuracy:0.918321
# 	Iter:136 train-loss:0.370806 valid-loss:0.430405  train-accuracy:0.929184 valid-accuracy:0.918591
# 	Iter:146 train-loss:0.365894 valid-loss:0.428423  train-accuracy:0.929932 valid-accuracy:0.918616
# 	Iter:156 train-loss:0.360815 valid-loss:0.426401  train-accuracy:0.930824 valid-accuracy:0.918998
# 	Iter:166 train-loss:0.356960 valid-loss:0.424610  train-accuracy:0.931461 valid-accuracy:0.919247
# 	Iter:176 train-loss:0.352662 valid-loss:0.423238  train-accuracy:0.932324 valid-accuracy:0.919417
# 	Iter:186 train-loss:0.348530 valid-loss:0.421590  train-accuracy:0.933385 valid-accuracy:0.920094
# 	Iter:196 train-loss:0.344851 valid-loss:0.420764  train-accuracy:0.934226 valid-accuracy:0.920455
# 	Iter:206 train-loss:0.341705 valid-loss:0.420226  train-accuracy:0.934903 valid-accuracy:0.920036
# 	Iter:216 train-loss:0.338312 valid-loss:0.419751  train-accuracy:0.935512 valid-accuracy:0.919762
# 	Iter:226 train-loss:0.335540 valid-loss:0.419548  train-accuracy:0.936050 valid-accuracy:0.919505
# 	Iter:236 train-loss:0.332375 valid-loss:0.419109  train-accuracy:0.936830 valid-accuracy:0.919800
# 	Iter:246 train-loss:0.329326 valid-loss:0.417772  train-accuracy:0.937528 valid-accuracy:0.920688
# 	Iter:256 train-loss:0.326660 valid-loss:0.417518  train-accuracy:0.938124 valid-accuracy:0.920153
# 	Iter:266 train-loss:0.323900 valid-loss:0.417027  train-accuracy:0.938765 valid-accuracy:0.919908
# 	Iter:276 train-loss:0.321540 valid-loss:0.417240  train-accuracy:0.939286 valid-accuracy:0.919306
# 	Iter:286 train-loss:0.318693 valid-loss:0.416935  train-accuracy:0.940218 valid-accuracy:0.918920
# 	Iter:296 train-loss:0.316678 valid-loss:0.417477  train-accuracy:0.940628 valid-accuracy:0.919202

# %%
# Model features
model.make_inspector().features()
# Out:
# ["Autocorrelation" (1; #0),
#  "ClusterProminence" (1; #1),
#  "ClusterShade" (1; #2),
#  "ClusterTendency" (1; #3),
#  "Contrast" (1; #4),
#  "Correlation" (1; #5),
#  "DifferenceAverage" (1; #6),
#  "DifferenceEntropy" (1; #7),
#  "DifferenceVariance" (1; #8),
#  "Id" (1; #9),
#  "Idm" (1; #10),
#  "Idmn" (1; #11),
#  "Idn" (1; #12),
#  "Imc1" (1; #13),
#  "Imc2" (1; #14),
#  "InverseVariance" (1; #15),
#  "JointAverage" (1; #16),
#  "JointEnergy" (1; #17),
#  "JointEntropy" (1; #18),
#  "MCC" (1; #19),
#  "MaximumProbability" (1; #20),
#  "SumAverage" (1; #21),
#  "SumEntropy" (1; #22),
#  "SumSquares" (1; #23)]

# %%
# Feature importance
model.make_inspector().variable_importances()
# Out:
# {'INV_MEAN_MIN_DEPTH': [("Idn" (1; #12), 0.24465711544348337),
#   ("Idmn" (1; #11), 0.2431220503785081),
#   ("ClusterShade" (1; #2), 0.19807916873915543),
#   ("JointAverage" (1; #16), 0.19725360159207495),
#   ("Autocorrelation" (1; #0), 0.1963507674645859),
#   ("SumAverage" (1; #21), 0.1953833095667986),
#   ("DifferenceVariance" (1; #8), 0.1940089444589353),
#   ("Imc1" (1; #13), 0.19376447836403768),
#   ("Correlation" (1; #5), 0.19097673278760666),
#   ("InverseVariance" (1; #15), 0.1893797104739635),
#   ("DifferenceEntropy" (1; #7), 0.1848667070913791),
#   ("DifferenceAverage" (1; #6), 0.18398326933660575),
#   ("Imc2" (1; #14), 0.18101311299455655),
#   ("MaximumProbability" (1; #20), 0.18081949606293526),
#   ("Contrast" (1; #4), 0.1799673989010799),
#   ("MCC" (1; #19), 0.17694884043498127),
#   ("SumEntropy" (1; #22), 0.17690549425506163),
#   ("ClusterProminence" (1; #1), 0.17568696678680784),
#   ("SumSquares" (1; #23), 0.17495778731859904),
#   ("Idm" (1; #10), 0.17489185433149984),
#   ("ClusterTendency" (1; #3), 0.17467790853651807),
#   ("Id" (1; #9), 0.1745063228043766),
#   ("JointEnergy" (1; #17), 0.17220095142188563),
#   ("JointEntropy" (1; #18), 0.17195887233030882)],
#  'NUM_AS_ROOT': [("Idmn" (1; #11), 82.0),
#   ("Idn" (1; #12), 78.0),
#   ("SumAverage" (1; #21), 21.0),
#   ("Imc1" (1; #13), 20.0),
#   ("JointAverage" (1; #16), 20.0),
#   ("Correlation" (1; #5), 19.0),
#   ("Autocorrelation" (1; #0), 10.0),
#   ("DifferenceAverage" (1; #6), 7.0),
#   ("InverseVariance" (1; #15), 7.0),
#   ("Imc2" (1; #14), 6.0),
#   ("DifferenceVariance" (1; #8), 5.0),
#   ("ClusterShade" (1; #2), 3.0),
#   ("Contrast" (1; #4), 2.0),
#   ("MCC" (1; #19), 2.0),
#   ("DifferenceEntropy" (1; #7), 1.0)],
#  'SUM_SCORE': [("Autocorrelation" (1; #0), 54520.73861520663),
#   ("SumAverage" (1; #21), 47468.48378994475),
#   ("Correlation" (1; #5), 47366.833825208356),
#   ("JointAverage" (1; #16), 39029.722201223994),
#   ("DifferenceVariance" (1; #8), 23982.275498040693),
#   ("Idn" (1; #12), 16592.15806678971),
#   ("InverseVariance" (1; #15), 11937.999112424111),
#   ("Idmn" (1; #11), 10619.878730710454),
#   ("Imc1" (1; #13), 10391.000981863284),
#   ("ClusterShade" (1; #2), 8599.60372854815),
#   ("DifferenceEntropy" (1; #7), 7270.574289422072),
#   ("DifferenceAverage" (1; #6), 6016.251433226241),
#   ("MaximumProbability" (1; #20), 4926.682422835075),
#   ("Contrast" (1; #4), 2086.7133359234),
#   ("Imc2" (1; #14), 1456.2501421905883),
#   ("SumEntropy" (1; #22), 1306.963410228214),
#   ("Id" (1; #9), 1281.8080330516623),
#   ("MCC" (1; #19), 883.4426669206712),
#   ("ClusterProminence" (1; #1), 820.8441471459661),
#   ("SumSquares" (1; #23), 742.9008226855864),
#   ("ClusterTendency" (1; #3), 629.3423360414872),
#   ("JointEnergy" (1; #17), 563.8643753353975),
#   ("Idm" (1; #10), 482.39163066536634),
#   ("JointEntropy" (1; #18), 453.728217415312)],
#  'NUM_NODES': [("Autocorrelation" (1; #0), 675.0),
#   ("ClusterShade" (1; #2), 662.0),
#   ("Idmn" (1; #11), 637.0),
#   ("Idn" (1; #12), 588.0),
#   ("JointAverage" (1; #16), 499.0),
#   ("SumAverage" (1; #21), 456.0),
#   ("DifferenceVariance" (1; #8), 424.0),
#   ("InverseVariance" (1; #15), 374.0),
#   ("Correlation" (1; #5), 346.0),
#   ("MaximumProbability" (1; #20), 313.0),
#   ("DifferenceEntropy" (1; #7), 304.0),
#   ("Imc1" (1; #13), 300.0),
#   ("Imc2" (1; #14), 278.0),
#   ("MCC" (1; #19), 248.0),
#   ("DifferenceAverage" (1; #6), 237.0),
#   ("SumEntropy" (1; #22), 230.0),
#   ("ClusterProminence" (1; #1), 208.0),
#   ("Contrast" (1; #4), 197.0),
#   ("Id" (1; #9), 144.0),
#   ("SumSquares" (1; #23), 134.0),
#   ("ClusterTendency" (1; #3), 125.0),
#   ("JointEnergy" (1; #17), 125.0),
#   ("Idm" (1; #10), 118.0),
#   ("JointEntropy" (1; #18), 101.0)]}

# %%
# Model self evaluation
model.make_inspector().evaluation()
# Out:
# Evaluation(num_examples=None, accuracy=0.9191649556159973, loss=0.41688522696495056, rmse=None, ndcg=None, aucs=None, auuc=None, qini=None)

# %%
logs = model.make_inspector().training_logs()

plt.figure(figsize=(12, 4))
plt.subplot(1, 2, 1)
plt.plot([log.num_trees for log in logs], [log.evaluation.accuracy for log in logs])
plt.xlabel("Number of trees")
plt.ylabel("Accuracy (out-of-bag)")
plt.subplot(1, 2, 2)
plt.plot([log.num_trees for log in logs], [log.evaluation.loss for log in logs])
plt.xlabel("Number of trees")
plt.ylabel("Logloss (out-of-bag)")
plt.show()

# %% [markdown]
# Calculate the score of our hold-out validation dataset

# %%
predictions = model.predict(val_ds)
y_true      = validation_data["label"]

from sklearn.metrics import roc_auc_score
ROC_AUC = roc_auc_score(y_true, predictions)
print("The ROC AUC score is %.5f" % ROC_AUC )
# Out:
#  1/46 [..............................] - ETA: 3s
# 10/46 [=====>........................] - ETA: 0s
# 20/46 [============>.................] - ETA: 0s
# 28/46 [=================>............] - ETA: 0s
# 37/46 [=======================>......] - ETA: 0s
# 46/46 [==============================] - 0s 6ms/step
# The ROC AUC score is 0.97681

# %%
# Compute binary classification metrics with sklearn
import numpy as np
from sklearn.metrics import (
    accuracy_score,
    precision_score,
    recall_score,
    f1_score,
    roc_auc_score,
    average_precision_score,
    confusion_matrix,
    classification_report,
    matthews_corrcoef,
    log_loss,
    brier_score_loss,
)

# Get predictions (probabilities or class labels)
preds = model.predict(test_ds)
# If model outputs probabilities, convert to labels by threshold 0.5
if preds.ndim == 2:
    # For TFDF classification, preds may be class probabilities with shape (N, 2)
    if preds.shape[1] == 2:
        pos_probs = preds[:, 1]
    else:
        # If single-probability column (positive class)
        pos_probs = preds[:, -1]
    y_pred = (pos_probs >= 0.5).astype(int)
else:
    # Already class labels
    y_pred = preds.astype(int)
    pos_probs = None

# Ground truth labels (must be 0/1 integers)
y_true = test_data["label"].astype(int).to_numpy()

# Core metrics
metrics = {}
metrics["accuracy"] = accuracy_score(y_true, y_pred)
metrics["precision"] = precision_score(y_true, y_pred, zero_division=0)
metrics["recall"] = recall_score(y_true, y_pred, zero_division=0)
metrics["f1"] = f1_score(y_true, y_pred, zero_division=0)
metrics["mcc"] = matthews_corrcoef(y_true, y_pred)

# Probabilistic metrics (only if we have probabilities)
if pos_probs is not None:
    metrics["roc_auc"] = roc_auc_score(y_true, pos_probs)
    metrics["pr_auc"] = average_precision_score(y_true, pos_probs)
    metrics["log_loss"] = log_loss(y_true, pos_probs, labels=[0,1])
    metrics["brier_score"] = brier_score_loss(y_true, pos_probs)

# Confusion matrix and detailed report
cm = confusion_matrix(y_true, y_pred, labels=[0,1])
report = classification_report(y_true, y_pred, digits=4)

print("Sklearn binary metrics:")
for k, v in metrics.items():
    print(f"{k}: {v:.4f}")
print("\nConfusion matrix:\n", cm)
print("\nClassification report:\n", report)
# Out:
#  1/91 [..............................] - ETA: 6s
#  8/91 [=>............................] - ETA: 0s
# 16/91 [====>.........................] - ETA: 0s
# 25/91 [=======>......................] - ETA: 0s
# 34/91 [==========>...................] - ETA: 0s
# 43/91 [=============>................] - ETA: 0s
# 52/91 [================>.............] - ETA: 0s
# 61/91 [===================>..........] - ETA: 0s
# 70/91 [======================>.......] - ETA: 0s
# 79/91 [=========================>....] - ETA: 0s
# 88/91 [============================>.] - ETA: 0s
# 91/91 [==============================] - 1s 6ms/step
# Sklearn binary metrics:
# accuracy: 0.9255
# precision: 0.4537
# recall: 0.9097
# f1: 0.6054
# mcc: 0.6116
# roc_auc: 0.9751
# pr_auc: 0.8100
# log_loss: 0.1836
# brier_score: 0.0548
#
# Confusion matrix:
#  [[78262  6199]
#  [  511  5148]]
#
# Classification report:
#                precision    recall  f1-score   support
#
#            0     0.9935    0.9266    0.9589     84461
#            1     0.4537    0.9097    0.6054      5659
#
#     accuracy                         0.9255     90120
#    macro avg     0.7236    0.9182    0.7822     90120
# weighted avg     0.9596    0.9255    0.9367     90120
