# %%
# Import packages and modules
import numpy  as np
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow_decision_forests as tfdf

from sklearn.model_selection import train_test_split
# Out:
# 2026-09-10 09:43:59.353900: I tensorflow/core/util/port.cc:113] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2026-09-10 09:43:59.780037: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2026-09-10 09:44:04.348197: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
# Check the version of TensorFlow Decision Forests
print("Found TensorFlow Decision Forests v" + tfdf.__version__)
# Out:
# Found TensorFlow Decision Forests v1.9.1

# %%
datasetPath = "dataset/10p/all/kernel3/"

# %%
# Parameters
datasetPath = "dataset/10p/all/kernel3/"

# %%
# train/validation/test = 70/10/20
train_data = pd.read_csv(f"{datasetPath}dataset.train.csv")
validation_data = pd.read_csv(f"{datasetPath}dataset.validation.csv")
test_data = pd.read_csv(f"{datasetPath}dataset.test.csv")

# %%
from sklearn.utils.class_weight import compute_class_weight

# tinh class weight tren tap train
classes = np.array([0, 1])
weights = compute_class_weight(class_weight="balanced", classes=classes, y=train_data["label"])
class_weight = {0: weights[0], 1: weights[1]}

# gan sample_weight cho tung dong
train_data["sample_weight"] = train_data["label"].map(class_weight)
validation_data["sample_weight"] = validation_data["label"].map(class_weight)
test_data["sample_weight"] = test_data["label"].map(class_weight)

# Convert the dataset into a TensorFlow dataset.
train_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    train_data, label="label", weight="sample_weight"
)         
val_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    validation_data, label="label", weight="sample_weight"
)
test_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    test_data, label="label", weight="sample_weight"
)
# Out:
# 2026-09-10 09:44:17.708309: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:984] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2026-09-10 09:44:17.709425: W tensorflow/core/common_runtime/gpu/gpu_device.cc:2251] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...

# %%
import keras

# %%
# %%time

# Train a Gradient Boosted Trees model.
model = tfdf.keras.GradientBoostedTreesModel()

# Add evaluation metrics
model.compile(
    metrics=["accuracy"]
)
model.fit(x=train_ds)

# # Train a Gradient Boosted Trees model.
# model = tfdf.keras.GradientBoostedTreesModel(num_trees=1500)
# model.fit(train_ds)
# Out:
# Use /tmp/tmps0eq9sue as temporary training directory
# Reading training dataset...
# [WARNING 26-09-10 09:44:17.9881 UTC gradient_boosted_trees.cc:1840] "goss_alpha" set but "sampling_method" not equal to "GOSS".
# [WARNING 26-09-10 09:44:17.9884 UTC gradient_boosted_trees.cc:1851] "goss_beta" set but "sampling_method" not equal to "GOSS".
# [WARNING 26-09-10 09:44:17.9884 UTC gradient_boosted_trees.cc:1865] "selective_gradient_boosting_ratio" set but "sampling_method" not equal to "SELGB".
# Training dataset read in 0:00:04.545624. Found 29597 examples.
# Training model...
# Model trained in 0:00:15.091581
# Compiling model...
# [INFO 26-09-10 09:44:37.6449 UTC kernel.cc:1233] Loading model from path /tmp/tmps0eq9sue/model/ with prefix 29ffa0caed734f36
# [INFO 26-09-10 09:44:37.6528 UTC quick_scorer_extended.cc:911] The binary was compiled without AVX2 support, but your CPU supports it. Enable it for faster model inference.
# [INFO 26-09-10 09:44:37.6534 UTC abstract_model.cc:1362] Engine "GradientBoostedTreesQuickScorerExtended" built
# [INFO 26-09-10 09:44:37.6535 UTC kernel.cc:1061] Use fast generic engine
# Model compiled.
# CPU times: user 2min 14s, sys: 4.68 s, total: 2min 19s
# Wall time: 23.5 s

# %%
# Evaluate the model
evaluate = model.evaluate(val_ds, return_dict=True)
print()

for name, value in evaluate.items():
    print(f"{name}: {value:.4f}")
# Out:
# WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 1/5 [=====>........................] - ETA: 12s - loss: 0.0000e+00 - accuracy: 0.9920
# 4/5 [=======================>......] - ETA: 0s - loss: 0.0000e+00 - accuracy: 0.9927
# 5/5 [==============================] - 3s 20ms/step - loss: 0.0000e+00 - accuracy: 0.9923
# loss: 0.0000
# accuracy: 0.9923

# %%
# Model Summary
model.summary()
# Out:
# Model: "gradient_boosted_trees_model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
# =================================================================
# Total params: 1 (1.00 Byte)
# Trainable params: 0 (0.00 Byte)
# Non-trainable params: 1 (1.00 Byte)
# _________________________________________________________________
# Type: "GRADIENT_BOOSTED_TREES"
# Task: CLASSIFICATION
# Label: "__LABEL"
#
# Input Features (93):
# 	10Percentile
# 	90Percentile
# 	Autocorrelation
# 	Busyness
# 	ClusterProminence
# 	ClusterShade
# 	ClusterTendency
# 	Coarseness
# 	Complexity
# 	Contrast
# 	Contrast.1
# 	Correlation
# 	DependenceEntropy
# 	DependenceNonUniformity
# 	DependenceNonUniformityNormalized
# 	DependenceVariance
# 	DifferenceAverage
# 	DifferenceEntropy
# 	DifferenceVariance
# 	Energy
# 	Entropy
# 	GrayLevelNonUniformity
# 	GrayLevelNonUniformity.1
# 	GrayLevelNonUniformity.2
# 	GrayLevelNonUniformityNormalized
# 	GrayLevelNonUniformityNormalized.1
# 	GrayLevelVariance
# 	GrayLevelVariance.1
# 	GrayLevelVariance.2
# 	HighGrayLevelEmphasis
# 	HighGrayLevelRunEmphasis
# 	HighGrayLevelZoneEmphasis
# 	Id
# 	Idm
# 	Idmn
# 	Idn
# 	Imc1
# 	Imc2
# 	InterquartileRange
# 	InverseVariance
# 	JointAverage
# 	JointEnergy
# 	JointEntropy
# 	Kurtosis
# 	LargeAreaEmphasis
# 	LargeAreaHighGrayLevelEmphasis
# 	LargeAreaLowGrayLevelEmphasis
# 	LargeDependenceEmphasis
# 	LargeDependenceHighGrayLevelEmphasis
# 	LargeDependenceLowGrayLevelEmphasis
# 	LongRunEmphasis
# 	LongRunHighGrayLevelEmphasis
# 	LongRunLowGrayLevelEmphasis
# 	LowGrayLevelEmphasis
# 	LowGrayLevelRunEmphasis
# 	LowGrayLevelZoneEmphasis
# 	MCC
# 	Maximum
# 	MaximumProbability
# 	Mean
# 	MeanAbsoluteDeviation
# 	Median
# 	Minimum
# 	Range
# 	RobustMeanAbsoluteDeviation
# 	RootMeanSquared
# 	RunEntropy
# 	RunLengthNonUniformity
# 	RunLengthNonUniformityNormalized
# 	RunPercentage
# 	RunVariance
# 	ShortRunEmphasis
# 	ShortRunHighGrayLevelEmphasis
# 	ShortRunLowGrayLevelEmphasis
# 	SizeZoneNonUniformity
# 	SizeZoneNonUniformityNormalized
# 	Skewness
# 	SmallAreaEmphasis
# 	SmallAreaHighGrayLevelEmphasis
# 	SmallAreaLowGrayLevelEmphasis
# 	SmallDependenceEmphasis
# 	SmallDependenceHighGrayLevelEmphasis
# 	SmallDependenceLowGrayLevelEmphasis
# 	Strength
# 	SumAverage
# 	SumEntropy
# 	SumSquares
# 	TotalEnergy
# 	Uniformity
# 	Variance
# 	ZoneEntropy
# 	ZonePercentage
# 	ZoneVariance
#
# Trained with weights
#
# Variable Importance: INV_MEAN_MIN_DEPTH:
#     1.                                  "Idn"  0.238044 ################
#     2.         "LongRunHighGrayLevelEmphasis"  0.238028 ###############
#     3. "LargeDependenceHighGrayLevelEmphasis"  0.218653 ###########
#     4.                           "Coarseness"  0.214905 ##########
#     5.                              "Maximum"  0.187715 ####
#     6.                          "Correlation"  0.186284 ###
#     7.             "GrayLevelNonUniformity.2"  0.185228 ###
#     8.                                 "Idmn"  0.184165 ###
#     9.                               "Median"  0.181650 ##
#    10.        "SmallAreaLowGrayLevelEmphasis"  0.180161 ##
#    11.       "LargeAreaHighGrayLevelEmphasis"  0.180146 ##
#    12.                             "Busyness"  0.179808 ##
#    13.                         "ClusterShade"  0.179178 ##
#    14.                         "10Percentile"  0.179147 #
#    15.                         "90Percentile"  0.178263 #
#    16.  "SmallDependenceLowGrayLevelEmphasis"  0.177803 #
#    17.                             "Skewness"  0.177137 #
#    18.                           "Contrast.1"  0.176534 #
#    19. "SmallDependenceHighGrayLevelEmphasis"  0.175765 #
#    20.                    "DifferenceAverage"  0.175050 #
#    21.            "HighGrayLevelZoneEmphasis"  0.174894
#    22.       "SmallAreaHighGrayLevelEmphasis"  0.174679
#    23.                             "Contrast"  0.174251
#    24.                    "DifferenceEntropy"  0.174239
#    25.             "LowGrayLevelZoneEmphasis"  0.174082
#    26.                   "DifferenceVariance"  0.173502
#    27.        "LargeAreaLowGrayLevelEmphasis"  0.173129
#    28.          "LongRunLowGrayLevelEmphasis"  0.172806
#    29.                      "Autocorrelation"  0.172765
#    30.  "LargeDependenceLowGrayLevelEmphasis"  0.172626
#    31.                                "Range"  0.172613
#    32.                              "Minimum"  0.172574
#    33.        "ShortRunHighGrayLevelEmphasis"  0.172362
#    34.                             "Kurtosis"  0.172343
#    35.                           "SumAverage"  0.172165
#    36.                          "ZoneEntropy"  0.172143
#    37.                    "SmallAreaEmphasis"  0.172100
#    38.                                 "Imc2"  0.172039
#    39.         "ShortRunLowGrayLevelEmphasis"  0.171974
#    40.                           "Complexity"  0.171932
#    41.                    "DependenceEntropy"  0.171906
#    42.                         "JointAverage"  0.171904
#    43.                      "InverseVariance"  0.171869
#    44.                   "MaximumProbability"  0.171766
#    45.             "GrayLevelNonUniformity.1"  0.171650
#    46.                                  "MCC"  0.171575
#    47.                                   "Id"  0.171552
#    48.                             "Strength"  0.171542
#    49.               "GrayLevelNonUniformity"  0.171497
#    50.     "GrayLevelNonUniformityNormalized"  0.171482
#    51.                           "Uniformity"  0.171479
#    52.                                 "Imc1"  0.171446
#    53.                                 "Mean"  0.171441
#    54.                 "LowGrayLevelEmphasis"  0.171371
#    55.          "RobustMeanAbsoluteDeviation"  0.171356
#    56.                           "SumEntropy"  0.171345
#    57.                   "InterquartileRange"  0.171332
#    58.      "SizeZoneNonUniformityNormalized"  0.171291
#    59.                   "DependenceVariance"  0.171276
#    60.                         "ZoneVariance"  0.171251
#    61.              "LowGrayLevelRunEmphasis"  0.171221
#    62.                    "LargeAreaEmphasis"  0.171177
#    63.             "HighGrayLevelRunEmphasis"  0.171145
#    64.                      "RootMeanSquared"  0.171112
#    65.                              "Entropy"  0.171093
#    66.                  "GrayLevelVariance.2"  0.171091
#    67.                          "RunVariance"  0.171075
#    68.                          "JointEnergy"  0.171052
#    69.    "DependenceNonUniformityNormalized"  0.171037
#    70.                       "ZonePercentage"  0.171018
#    71.   "GrayLevelNonUniformityNormalized.1"  0.171006
#    72.                "SizeZoneNonUniformity"  0.170995
#    73.              "DependenceNonUniformity"  0.170988
#    74.                           "SumSquares"  0.170983
#    75.              "SmallDependenceEmphasis"  0.170961
#    76.                      "ClusterTendency"  0.170958
#    77.                    "GrayLevelVariance"  0.170944
#    78.                  "GrayLevelVariance.1"  0.170939
#    79.              "LargeDependenceEmphasis"  0.170926
#    80.                          "TotalEnergy"  0.170891
#    81.                "MeanAbsoluteDeviation"  0.170889
#    82.                    "ClusterProminence"  0.170868
#    83.                "HighGrayLevelEmphasis"  0.170860
#    84.                      "LongRunEmphasis"  0.170856
#    85.                                  "Idm"  0.170848
#    86.                           "RunEntropy"  0.170826
#    87.                         "JointEntropy"  0.170812
#    88.     "RunLengthNonUniformityNormalized"  0.170802
#    89.               "RunLengthNonUniformity"  0.170798
#    90.                        "RunPercentage"  0.170785
#    91.                     "ShortRunEmphasis"  0.170778
#    92.                               "Energy"  0.170774
#    93.                             "Variance"  0.170738
#
# Variable Importance: NUM_AS_ROOT:
#     1.         "LongRunHighGrayLevelEmphasis" 39.000000 ################
#     2. "LargeDependenceHighGrayLevelEmphasis" 20.000000 ########
#     3.                           "Coarseness" 18.000000 #######
#     4.                          "Correlation"  9.000000 ###
#     5.                                  "Idn"  6.000000 ##
#     6.                         "10Percentile"  5.000000 #
#     7.             "GrayLevelNonUniformity.2"  5.000000 #
#     8.                              "Maximum"  5.000000 #
#     9.        "SmallAreaLowGrayLevelEmphasis"  5.000000 #
#    10.                               "Median"  3.000000
#    11.                                 "Idmn"  2.000000
#    12.                         "90Percentile"  1.000000
#    13.                      "Autocorrelation"  1.000000
#    14.                             "Busyness"  1.000000
#    15.                    "DifferenceEntropy"  1.000000
#    16.             "LowGrayLevelZoneEmphasis"  1.000000
#    17.  "SmallDependenceLowGrayLevelEmphasis"  1.000000
#
# Variable Importance: NUM_NODES:
#     1.                                  "Idn" 378.000000 ################
#     2.                                 "Idmn" 157.000000 ######
#     3.                           "Coarseness" 155.000000 ######
#     4. "LargeDependenceHighGrayLevelEmphasis" 154.000000 ######
#     5.         "LongRunHighGrayLevelEmphasis" 153.000000 ######
#     6.       "LargeAreaHighGrayLevelEmphasis" 121.000000 #####
#     7.                             "Busyness" 110.000000 ####
#     8.                              "Maximum" 104.000000 ####
#     9.                               "Median" 94.000000 ###
#    10.                         "90Percentile" 91.000000 ###
#    11.             "GrayLevelNonUniformity.2" 86.000000 ###
#    12.  "SmallDependenceLowGrayLevelEmphasis" 85.000000 ###
#    13.                           "Contrast.1" 79.000000 ###
#    14.                         "ClusterShade" 78.000000 ###
#    15.                             "Skewness" 73.000000 ###
#    16.                          "Correlation" 60.000000 ##
#    17.                    "DifferenceAverage" 57.000000 ##
#    18.                             "Contrast" 55.000000 ##
#    19.        "SmallAreaLowGrayLevelEmphasis" 55.000000 ##
#    20.                         "10Percentile" 54.000000 ##
#    21. "SmallDependenceHighGrayLevelEmphasis" 45.000000 #
#    22.                   "DifferenceVariance" 41.000000 #
#    23.             "LowGrayLevelZoneEmphasis" 40.000000 #
#    24.                    "DifferenceEntropy" 39.000000 #
#    25.                              "Minimum" 38.000000 #
#    26.  "LargeDependenceLowGrayLevelEmphasis" 37.000000 #
#    27.       "SmallAreaHighGrayLevelEmphasis" 37.000000 #
#    28.            "HighGrayLevelZoneEmphasis" 31.000000 #
#    29.                             "Kurtosis" 30.000000 #
#    30.        "LargeAreaLowGrayLevelEmphasis" 30.000000 #
#    31.                      "InverseVariance" 25.000000 #
#    32.          "LongRunLowGrayLevelEmphasis" 25.000000 #
#    33.                          "ZoneEntropy" 24.000000
#    34.                                  "MCC" 23.000000
#    35.                                "Range" 23.000000
#    36.                    "DependenceEntropy" 22.000000
#    37.        "ShortRunHighGrayLevelEmphasis" 21.000000
#    38.                           "Complexity" 20.000000
#    39.                   "DependenceVariance" 20.000000
#    40.                   "MaximumProbability" 20.000000
#    41.                           "SumAverage" 19.000000
#    42.                    "SmallAreaEmphasis" 18.000000
#    43.                             "Strength" 18.000000
#    44.          "RobustMeanAbsoluteDeviation" 17.000000
#    45.         "ShortRunLowGrayLevelEmphasis" 17.000000
#    46.                  "GrayLevelVariance.2" 15.000000
#    47.   "GrayLevelNonUniformityNormalized.1" 14.000000
#    48.                                 "Imc1" 14.000000
#    49.                                 "Imc2" 14.000000
#    50.                      "Autocorrelation" 13.000000
#    51.                                   "Id" 13.000000
#    52.                   "InterquartileRange" 13.000000
#    53.             "GrayLevelNonUniformity.1" 12.000000
#    54.             "HighGrayLevelRunEmphasis" 12.000000
#    55.                         "JointAverage" 12.000000
#    56.              "LowGrayLevelRunEmphasis" 12.000000
#    57.      "SizeZoneNonUniformityNormalized" 12.000000
#    58.                              "Entropy" 11.000000
#    59.                          "JointEnergy" 10.000000
#    60.                           "SumEntropy" 10.000000
#    61.                           "Uniformity"  9.000000
#    62.              "SmallDependenceEmphasis"  8.000000
#    63.                      "ClusterTendency"  7.000000
#    64.    "DependenceNonUniformityNormalized"  7.000000
#    65.               "GrayLevelNonUniformity"  7.000000
#    66.     "GrayLevelNonUniformityNormalized"  7.000000
#    67.                 "LowGrayLevelEmphasis"  7.000000
#    68.                                 "Mean"  7.000000
#    69.                      "RootMeanSquared"  7.000000
#    70.                          "RunVariance"  7.000000
#    71.                "SizeZoneNonUniformity"  7.000000
#    72.              "DependenceNonUniformity"  6.000000
#    73.                    "LargeAreaEmphasis"  6.000000
#    74.                "MeanAbsoluteDeviation"  6.000000
#    75.                "HighGrayLevelEmphasis"  5.000000
#    76.                                  "Idm"  5.000000
#    77.                         "JointEntropy"  5.000000
#    78.              "LargeDependenceEmphasis"  5.000000
#    79.     "RunLengthNonUniformityNormalized"  5.000000
#    80.                         "ZoneVariance"  5.000000
#    81.                    "ClusterProminence"  4.000000
#    82.                      "LongRunEmphasis"  4.000000
#    83.                           "RunEntropy"  4.000000
#    84.               "RunLengthNonUniformity"  4.000000
#    85.                       "ZonePercentage"  4.000000
#    86.                               "Energy"  3.000000
#    87.                    "GrayLevelVariance"  3.000000
#    88.                  "GrayLevelVariance.1"  3.000000
#    89.                           "SumSquares"  3.000000
#    90.                          "TotalEnergy"  3.000000
#    91.                        "RunPercentage"  2.000000
#    92.                     "ShortRunEmphasis"  1.000000
#    93.                             "Variance"  1.000000
#
# Variable Importance: SUM_SCORE:
#     1.         "LongRunHighGrayLevelEmphasis" 18948.833215 ################
#     2.                                  "Idn" 2849.013295 ##
#     3. "LargeDependenceHighGrayLevelEmphasis" 2397.578018 ##
#     4.                           "Coarseness" 1140.640061
#     5.             "GrayLevelNonUniformity.2" 1014.431681
#     6.       "LargeAreaHighGrayLevelEmphasis" 939.157918
#     7.                              "Maximum" 694.124997
#     8.                             "Busyness" 637.887679
#     9.                             "Skewness" 478.136345
#    10.                               "Median" 473.484804
#    11.                         "90Percentile" 442.011161
#    12.                                 "Idmn" 434.458062
#    13.                           "Contrast.1" 329.629849
#    14.  "SmallDependenceLowGrayLevelEmphasis" 227.134419
#    15.                    "DifferenceAverage" 184.252614
#    16.                             "Contrast" 161.082875
#    17.                    "DifferenceEntropy" 160.744875
#    18. "SmallDependenceHighGrayLevelEmphasis" 141.197956
#    19.                      "Autocorrelation" 140.664354
#    20.       "SmallAreaHighGrayLevelEmphasis" 139.339344
#    21.                         "ClusterShade" 138.020523
#    22.  "LargeDependenceLowGrayLevelEmphasis" 131.715722
#    23.                   "DifferenceVariance" 131.379058
#    24.                              "Minimum" 114.024728
#    25.        "SmallAreaLowGrayLevelEmphasis" 108.077152
#    26.        "LargeAreaLowGrayLevelEmphasis" 92.444554
#    27.                         "10Percentile" 89.075965
#    28.                          "Correlation" 71.228260
#    29.             "LowGrayLevelZoneEmphasis" 70.979863
#    30.                             "Kurtosis" 62.521387
#    31.                                   "Id" 62.498668
#    32.                           "SumAverage" 61.885913
#    33.                                  "MCC" 58.351325
#    34.                   "MaximumProbability" 46.838997
#    35.                      "InverseVariance" 44.231589
#    36.            "HighGrayLevelZoneEmphasis" 43.169125
#    37.                    "DependenceEntropy" 41.146790
#    38.              "LowGrayLevelRunEmphasis" 39.478041
#    39.             "GrayLevelNonUniformity.1" 39.096940
#    40.      "SizeZoneNonUniformityNormalized" 35.819950
#    41.        "ShortRunHighGrayLevelEmphasis" 35.561150
#    42.   "GrayLevelNonUniformityNormalized.1" 33.988966
#    43.          "LongRunLowGrayLevelEmphasis" 32.248534
#    44.                   "DependenceVariance" 31.159146
#    45.                           "SumEntropy" 29.661755
#    46.             "HighGrayLevelRunEmphasis" 25.749060
#    47.    "DependenceNonUniformityNormalized" 23.717597
#    48.                       "ZonePercentage" 23.376749
#    49.                           "Complexity" 23.143891
#    50.                                "Range" 22.821470
#    51.                             "Strength" 22.393257
#    52.                                 "Imc2" 22.166364
#    53.                    "SmallAreaEmphasis" 21.389120
#    54.                           "Uniformity" 20.283622
#    55.                "HighGrayLevelEmphasis" 19.758411
#    56.                 "LowGrayLevelEmphasis" 17.461791
#    57.                          "ZoneEntropy" 17.172461
#    58.                                 "Imc1" 15.735787
#    59.                         "JointAverage" 15.659898
#    60.              "DependenceNonUniformity" 15.583689
#    61.          "RobustMeanAbsoluteDeviation" 15.499312
#    62.     "GrayLevelNonUniformityNormalized" 15.073915
#    63.         "ShortRunLowGrayLevelEmphasis" 14.760234
#    64.                      "RootMeanSquared" 14.484125
#    65.                    "ClusterProminence" 14.450072
#    66.                  "GrayLevelVariance.2" 14.183844
#    67.               "GrayLevelNonUniformity" 13.170391
#    68.              "SmallDependenceEmphasis" 11.640568
#    69.                          "RunVariance" 10.632898
#    70.                                  "Idm"  9.742037
#    71.                              "Entropy"  9.380080
#    72.                      "ClusterTendency"  8.806739
#    73.                   "InterquartileRange"  8.264409
#    74.                     "ShortRunEmphasis"  7.649265
#    75.                           "SumSquares"  7.474637
#    76.                                 "Mean"  7.139138
#    77.              "LargeDependenceEmphasis"  6.741827
#    78.                          "JointEnergy"  5.598547
#    79.                    "LargeAreaEmphasis"  5.042355
#    80.     "RunLengthNonUniformityNormalized"  5.023753
#    81.                "MeanAbsoluteDeviation"  4.447103
#    82.                "SizeZoneNonUniformity"  4.166184
#    83.                    "GrayLevelVariance"  4.032536
#    84.                           "RunEntropy"  3.992415
#    85.                          "TotalEnergy"  3.075536
#    86.                      "LongRunEmphasis"  2.810250
#    87.                         "ZoneVariance"  2.738578
#    88.                         "JointEntropy"  2.245137
#    89.                  "GrayLevelVariance.1"  1.557695
#    90.               "RunLengthNonUniformity"  1.121395
#    91.                        "RunPercentage"  0.913094
#    92.                             "Variance"  0.747803
#    93.                               "Energy"  0.304400
#
#
#
# Loss: BINOMIAL_LOG_LIKELIHOOD
# Validation loss value: 0.25817
# Number of trees per iteration: 1
# Node format: NOT_SET
# Number of trees: 123
# Total number of nodes: 6589
#
# Number of nodes by tree:
# Count: 123 Average: 53.5691 StdDev: 7.82541
# Min: 29 Max: 63 Ignored: 0
# ----------------------------------------------
# [ 29, 30)  1   0.81%   0.81% #
# [ 30, 32)  1   0.81%   1.63% #
# [ 32, 34)  1   0.81%   2.44% #
# [ 34, 36)  1   0.81%   3.25% #
# [ 36, 37)  0   0.00%   3.25%
# [ 37, 39)  1   0.81%   4.07% #
# [ 39, 41)  1   0.81%   4.88% #
# [ 41, 43)  2   1.63%   6.50% #
# [ 43, 44)  9   7.32%  13.82% ######
# [ 44, 46)  5   4.07%  17.89% ###
# [ 46, 48)  9   7.32%  25.20% ######
# [ 48, 50)  4   3.25%  28.46% ###
# [ 50, 51)  0   0.00%  28.46%
# [ 51, 53) 15  12.20%  40.65% #########
# [ 53, 55)  7   5.69%  46.34% ####
# [ 55, 57)  9   7.32%  53.66% ######
# [ 57, 58)  9   7.32%  60.98% ######
# [ 58, 60) 16  13.01%  73.98% ##########
# [ 60, 62) 16  13.01%  86.99% ##########
# [ 62, 63] 16  13.01% 100.00% ##########
#
# Depth by leafs:
# Count: 3356 Average: 4.87515 StdDev: 0.438971
# Min: 2 Max: 5 Ignored: 0
# ----------------------------------------------
# [ 2, 3)   21   0.63%   0.63%
# [ 3, 4)   77   2.29%   2.92%
# [ 4, 5)  202   6.02%   8.94% #
# [ 5, 5] 3056  91.06% 100.00% ##########
#
# Number of training obs by leaf:
# Count: 3356 Average: 977.073 StdDev: 2442.17
# Min: 5 Max: 24740 Ignored: 0
# ----------------------------------------------
# [     5,  1241) 2798  83.37%  83.37% ##########
# [  1241,  2478)  207   6.17%  89.54% #
# [  2478,  3715)   89   2.65%  92.19%
# [  3715,  4952)   61   1.82%  94.01%
# [  4952,  6189)   37   1.10%  95.11%
# [  6189,  7425)   35   1.04%  96.16%
# [  7425,  8662)   27   0.80%  96.96%
# [  8662,  9899)   30   0.89%  97.85%
# [  9899, 11136)   19   0.57%  98.42%
# [ 11136, 12373)   12   0.36%  98.78%
# [ 12373, 13609)   13   0.39%  99.17%
# [ 13609, 14846)   14   0.42%  99.58%
# [ 14846, 16083)    8   0.24%  99.82%
# [ 16083, 17320)    1   0.03%  99.85%
# [ 17320, 18557)    1   0.03%  99.88%
# [ 18557, 19793)    2   0.06%  99.94%
# [ 19793, 21030)    0   0.00%  99.94%
# [ 21030, 22267)    0   0.00%  99.94%
# [ 22267, 23504)    0   0.00%  99.94%
# [ 23504, 24740]    2   0.06% 100.00%
#
# Attribute in nodes:
# 	378 : Idn [NUMERICAL]
# 	157 : Idmn [NUMERICAL]
# 	155 : Coarseness [NUMERICAL]
# 	154 : LargeDependenceHighGrayLevelEmphasis [NUMERICAL]
# 	153 : LongRunHighGrayLevelEmphasis [NUMERICAL]
# 	121 : LargeAreaHighGrayLevelEmphasis [NUMERICAL]
# 	110 : Busyness [NUMERICAL]
# 	104 : Maximum [NUMERICAL]
# 	94 : Median [NUMERICAL]
# 	91 : 90Percentile [NUMERICAL]
# 	86 : GrayLevelNonUniformity.2 [NUMERICAL]
# 	85 : SmallDependenceLowGrayLevelEmphasis [NUMERICAL]
# 	79 : Contrast.1 [NUMERICAL]
# 	78 : ClusterShade [NUMERICAL]
# 	73 : Skewness [NUMERICAL]
# 	60 : Correlation [NUMERICAL]
# 	57 : DifferenceAverage [NUMERICAL]
# 	55 : SmallAreaLowGrayLevelEmphasis [NUMERICAL]
# 	55 : Contrast [NUMERICAL]
# 	54 : 10Percentile [NUMERICAL]
# 	45 : SmallDependenceHighGrayLevelEmphasis [NUMERICAL]
# 	41 : DifferenceVariance [NUMERICAL]
# 	40 : LowGrayLevelZoneEmphasis [NUMERICAL]
# 	39 : DifferenceEntropy [NUMERICAL]
# 	38 : Minimum [NUMERICAL]
# 	37 : SmallAreaHighGrayLevelEmphasis [NUMERICAL]
# 	37 : LargeDependenceLowGrayLevelEmphasis [NUMERICAL]
# 	31 : HighGrayLevelZoneEmphasis [NUMERICAL]
# 	30 : LargeAreaLowGrayLevelEmphasis [NUMERICAL]
# 	30 : Kurtosis [NUMERICAL]
# 	25 : LongRunLowGrayLevelEmphasis [NUMERICAL]
# 	25 : InverseVariance [NUMERICAL]
# 	24 : ZoneEntropy [NUMERICAL]
# 	23 : Range [NUMERICAL]
# 	23 : MCC [NUMERICAL]
# 	22 : DependenceEntropy [NUMERICAL]
# 	21 : ShortRunHighGrayLevelEmphasis [NUMERICAL]
# 	20 : MaximumProbability [NUMERICAL]
# 	20 : DependenceVariance [NUMERICAL]
# 	20 : Complexity [NUMERICAL]
# 	19 : SumAverage [NUMERICAL]
# 	18 : Strength [NUMERICAL]
# 	18 : SmallAreaEmphasis [NUMERICAL]
# 	17 : ShortRunLowGrayLevelEmphasis [NUMERICAL]
# 	17 : RobustMeanAbsoluteDeviation [NUMERICAL]
# 	15 : GrayLevelVariance.2 [NUMERICAL]
# 	14 : Imc2 [NUMERICAL]
# 	14 : Imc1 [NUMERICAL]
# 	14 : GrayLevelNonUniformityNormalized.1 [NUMERICAL]
# 	13 : InterquartileRange [NUMERICAL]
# 	13 : Id [NUMERICAL]
# 	13 : Autocorrelation [NUMERICAL]
# 	12 : SizeZoneNonUniformityNormalized [NUMERICAL]
# 	12 : LowGrayLevelRunEmphasis [NUMERICAL]
# 	12 : JointAverage [NUMERICAL]
# 	12 : HighGrayLevelRunEmphasis [NUMERICAL]
# 	12 : GrayLevelNonUniformity.1 [NUMERICAL]
# 	11 : Entropy [NUMERICAL]
# 	10 : SumEntropy [NUMERICAL]
# 	10 : JointEnergy [NUMERICAL]
# 	9 : Uniformity [NUMERICAL]
# 	8 : SmallDependenceEmphasis [NUMERICAL]
# 	7 : SizeZoneNonUniformity [NUMERICAL]
# 	7 : RunVariance [NUMERICAL]
# 	7 : RootMeanSquared [NUMERICAL]
# 	7 : Mean [NUMERICAL]
# 	7 : LowGrayLevelEmphasis [NUMERICAL]
# 	7 : GrayLevelNonUniformityNormalized [NUMERICAL]
# 	7 : GrayLevelNonUniformity [NUMERICAL]
# 	7 : DependenceNonUniformityNormalized [NUMERICAL]
# 	7 : ClusterTendency [NUMERICAL]
# 	6 : MeanAbsoluteDeviation [NUMERICAL]
# 	6 : LargeAreaEmphasis [NUMERICAL]
# 	6 : DependenceNonUniformity [NUMERICAL]
# 	5 : ZoneVariance [NUMERICAL]
# 	5 : RunLengthNonUniformityNormalized [NUMERICAL]
# 	5 : LargeDependenceEmphasis [NUMERICAL]
# 	5 : JointEntropy [NUMERICAL]
# 	5 : Idm [NUMERICAL]
# 	5 : HighGrayLevelEmphasis [NUMERICAL]
# 	4 : ZonePercentage [NUMERICAL]
# 	4 : RunLengthNonUniformity [NUMERICAL]
# 	4 : RunEntropy [NUMERICAL]
# 	4 : LongRunEmphasis [NUMERICAL]
# 	4 : ClusterProminence [NUMERICAL]
# 	3 : TotalEnergy [NUMERICAL]
# 	3 : SumSquares [NUMERICAL]
# 	3 : GrayLevelVariance.1 [NUMERICAL]
# 	3 : GrayLevelVariance [NUMERICAL]
# 	3 : Energy [NUMERICAL]
# 	2 : RunPercentage [NUMERICAL]
# 	1 : Variance [NUMERICAL]
# 	1 : ShortRunEmphasis [NUMERICAL]
#
# Attribute in nodes with depth <= 0:
# 	39 : LongRunHighGrayLevelEmphasis [NUMERICAL]
# 	20 : LargeDependenceHighGrayLevelEmphasis [NUMERICAL]
# 	18 : Coarseness [NUMERICAL]
# 	9 : Correlation [NUMERICAL]
# 	6 : Idn [NUMERICAL]
# 	5 : SmallAreaLowGrayLevelEmphasis [NUMERICAL]
# 	5 : Maximum [NUMERICAL]
# 	5 : GrayLevelNonUniformity.2 [NUMERICAL]
# 	5 : 10Percentile [NUMERICAL]
# 	3 : Median [NUMERICAL]
# 	2 : Idmn [NUMERICAL]
# 	1 : SmallDependenceLowGrayLevelEmphasis [NUMERICAL]
# 	1 : LowGrayLevelZoneEmphasis [NUMERICAL]
# 	1 : DifferenceEntropy [NUMERICAL]
# 	1 : Busyness [NUMERICAL]
# 	1 : Autocorrelation [NUMERICAL]
# 	1 : 90Percentile [NUMERICAL]
#
# Attribute in nodes with depth <= 1:
# 	67 : LongRunHighGrayLevelEmphasis [NUMERICAL]
# 	56 : Idn [NUMERICAL]
# 	46 : LargeDependenceHighGrayLevelEmphasis [NUMERICAL]
# 	40 : Coarseness [NUMERICAL]
# 	20 : Maximum [NUMERICAL]
# 	17 : Correlation [NUMERICAL]
# 	13 : GrayLevelNonUniformity.2 [NUMERICAL]
# 	13 : ClusterShade [NUMERICAL]
# 	9 : SmallAreaLowGrayLevelEmphasis [NUMERICAL]
# 	8 : Idmn [NUMERICAL]
# 	8 : 10Percentile [NUMERICAL]
# 	7 : Median [NUMERICAL]
# 	6 : Busyness [NUMERICAL]
# 	5 : SmallDependenceLowGrayLevelEmphasis [NUMERICAL]
# 	5 : SmallDependenceHighGrayLevelEmphasis [NUMERICAL]
# 	5 : Skewness [NUMERICAL]
# 	5 : HighGrayLevelZoneEmphasis [NUMERICAL]
# 	4 : 90Percentile [NUMERICAL]
# 	3 : LongRunLowGrayLevelEmphasis [NUMERICAL]
# 	3 : LargeAreaLowGrayLevelEmphasis [NUMERICAL]
# 	3 : LargeAreaHighGrayLevelEmphasis [NUMERICAL]
# 	3 : Contrast.1 [NUMERICAL]
# 	2 : SmallAreaHighGrayLevelEmphasis [NUMERICAL]
# 	2 : JointAverage [NUMERICAL]
# 	2 : DifferenceVariance [NUMERICAL]
# 	2 : Autocorrelation [NUMERICAL]
# 	1 : ZoneVariance [NUMERICAL]
# 	1 : ZoneEntropy [NUMERICAL]
# 	1 : SumAverage [NUMERICAL]
# 	1 : SmallAreaEmphasis [NUMERICAL]
# 	1 : ShortRunLowGrayLevelEmphasis [NUMERICAL]
# 	1 : ShortRunHighGrayLevelEmphasis [NUMERICAL]
# 	1 : Minimum [NUMERICAL]
# 	1 : Mean [NUMERICAL]
# 	1 : LowGrayLevelZoneEmphasis [NUMERICAL]
# 	1 : Kurtosis [NUMERICAL]
# 	1 : GrayLevelNonUniformityNormalized [NUMERICAL]
# 	1 : GrayLevelNonUniformity.1 [NUMERICAL]
# 	1 : DifferenceEntropy [NUMERICAL]
# 	1 : DifferenceAverage [NUMERICAL]
# 	1 : Contrast [NUMERICAL]
#
# Attribute in nodes with depth <= 2:
# 	121 : Idn [NUMERICAL]
# 	75 : LongRunHighGrayLevelEmphasis [NUMERICAL]
# 	64 : Coarseness [NUMERICAL]
# 	61 : LargeDependenceHighGrayLevelEmphasis [NUMERICAL]
# 	37 : Idmn [NUMERICAL]
# 	35 : GrayLevelNonUniformity.2 [NUMERICAL]
# 	30 : Maximum [NUMERICAL]
# 	28 : LargeAreaHighGrayLevelEmphasis [NUMERICAL]
# 	28 : Correlation [NUMERICAL]
# 	24 : Median [NUMERICAL]
# 	23 : ClusterShade [NUMERICAL]
# 	21 : Busyness [NUMERICAL]
# 	19 : 90Percentile [NUMERICAL]
# 	17 : Skewness [NUMERICAL]
# 	16 : Contrast.1 [NUMERICAL]
# 	15 : SmallDependenceHighGrayLevelEmphasis [NUMERICAL]
# 	15 : SmallAreaLowGrayLevelEmphasis [NUMERICAL]
# 	14 : SmallDependenceLowGrayLevelEmphasis [NUMERICAL]
# 	13 : DifferenceAverage [NUMERICAL]
# 	12 : SmallAreaHighGrayLevelEmphasis [NUMERICAL]
# 	11 : HighGrayLevelZoneEmphasis [NUMERICAL]
# 	11 : 10Percentile [NUMERICAL]
# 	8 : LowGrayLevelZoneEmphasis [NUMERICAL]
# 	8 : Contrast [NUMERICAL]
# 	7 : ZoneEntropy [NUMERICAL]
# 	7 : Range [NUMERICAL]
# 	7 : Imc2 [NUMERICAL]
# 	7 : DifferenceVariance [NUMERICAL]
# 	7 : DifferenceEntropy [NUMERICAL]
# 	6 : ShortRunHighGrayLevelEmphasis [NUMERICAL]
# 	6 : LongRunLowGrayLevelEmphasis [NUMERICAL]
# 	6 : LargeAreaLowGrayLevelEmphasis [NUMERICAL]
# 	4 : LargeDependenceLowGrayLevelEmphasis [NUMERICAL]
# 	4 : Kurtosis [NUMERICAL]
# 	4 : JointAverage [NUMERICAL]
# 	4 : DependenceEntropy [NUMERICAL]
# 	4 : Autocorrelation [NUMERICAL]
# 	3 : Uniformity [NUMERICAL]
# 	3 : SumAverage [NUMERICAL]
# 	3 : SmallAreaEmphasis [NUMERICAL]
# 	3 : ShortRunLowGrayLevelEmphasis [NUMERICAL]
# 	3 : Id [NUMERICAL]
# 	3 : GrayLevelNonUniformity [NUMERICAL]
# 	3 : Complexity [NUMERICAL]
# 	2 : SumEntropy [NUMERICAL]
# 	2 : Strength [NUMERICAL]
# 	2 : RobustMeanAbsoluteDeviation [NUMERICAL]
# 	2 : Minimum [NUMERICAL]
# 	2 : MaximumProbability [NUMERICAL]
# 	2 : MCC [NUMERICAL]
# 	2 : LowGrayLevelRunEmphasis [NUMERICAL]
# 	2 : LowGrayLevelEmphasis [NUMERICAL]
# 	2 : LargeAreaEmphasis [NUMERICAL]
# 	2 : InverseVariance [NUMERICAL]
# 	2 : Imc1 [NUMERICAL]
# 	2 : GrayLevelNonUniformity.1 [NUMERICAL]
# 	1 : ZoneVariance [NUMERICAL]
# 	1 : ZonePercentage [NUMERICAL]
# 	1 : SumSquares [NUMERICAL]
# 	1 : SmallDependenceEmphasis [NUMERICAL]
# 	1 : SizeZoneNonUniformityNormalized [NUMERICAL]
# 	1 : SizeZoneNonUniformity [NUMERICAL]
# 	1 : RunVariance [NUMERICAL]
# 	1 : RootMeanSquared [NUMERICAL]
# 	1 : Mean [NUMERICAL]
# 	1 : InterquartileRange [NUMERICAL]
# 	1 : Idm [NUMERICAL]
# 	1 : HighGrayLevelRunEmphasis [NUMERICAL]
# 	1 : GrayLevelVariance.1 [NUMERICAL]
# 	1 : GrayLevelVariance [NUMERICAL]
# 	1 : GrayLevelNonUniformityNormalized [NUMERICAL]
# 	1 : Entropy [NUMERICAL]
#
# Attribute in nodes with depth <= 3:
# 	213 : Idn [NUMERICAL]
# 	103 : LongRunHighGrayLevelEmphasis [NUMERICAL]
# 	100 : Coarseness [NUMERICAL]
# 	96 : LargeDependenceHighGrayLevelEmphasis [NUMERICAL]
# 	73 : LargeAreaHighGrayLevelEmphasis [NUMERICAL]
# 	67 : Idmn [NUMERICAL]
# 	57 : Maximum [NUMERICAL]
# 	52 : Median [NUMERICAL]
# 	52 : GrayLevelNonUniformity.2 [NUMERICAL]
# 	51 : Busyness [NUMERICAL]
# 	45 : SmallDependenceLowGrayLevelEmphasis [NUMERICAL]
# 	42 : ClusterShade [NUMERICAL]
# 	41 : Correlation [NUMERICAL]
# 	40 : 90Percentile [NUMERICAL]
# 	39 : Contrast.1 [NUMERICAL]
# 	35 : DifferenceAverage [NUMERICAL]
# 	32 : SmallAreaLowGrayLevelEmphasis [NUMERICAL]
# 	29 : Skewness [NUMERICAL]
# 	28 : 10Percentile [NUMERICAL]
# 	26 : SmallDependenceHighGrayLevelEmphasis [NUMERICAL]
# 	26 : Contrast [NUMERICAL]
# 	23 : HighGrayLevelZoneEmphasis [NUMERICAL]
# 	22 : SmallAreaHighGrayLevelEmphasis [NUMERICAL]
# 	22 : DifferenceVariance [NUMERICAL]
# 	21 : DifferenceEntropy [NUMERICAL]
# 	20 : LowGrayLevelZoneEmphasis [NUMERICAL]
# 	17 : LargeDependenceLowGrayLevelEmphasis [NUMERICAL]
# 	15 : Minimum [NUMERICAL]
# 	14 : LargeAreaLowGrayLevelEmphasis [NUMERICAL]
# 	13 : Range [NUMERICAL]
# 	13 : Complexity [NUMERICAL]
# 	12 : ZoneEntropy [NUMERICAL]
# 	11 : MaximumProbability [NUMERICAL]
# 	11 : InverseVariance [NUMERICAL]
# 	11 : Imc2 [NUMERICAL]
# 	10 : SumAverage [NUMERICAL]
# 	10 : ShortRunHighGrayLevelEmphasis [NUMERICAL]
# 	10 : Kurtosis [NUMERICAL]
# 	9 : SmallAreaEmphasis [NUMERICAL]
# 	9 : DependenceEntropy [NUMERICAL]
# 	8 : LongRunLowGrayLevelEmphasis [NUMERICAL]
# 	7 : Strength [NUMERICAL]
# 	7 : SizeZoneNonUniformityNormalized [NUMERICAL]
# 	7 : ShortRunLowGrayLevelEmphasis [NUMERICAL]
# 	7 : MCC [NUMERICAL]
# 	7 : JointAverage [NUMERICAL]
# 	7 : InterquartileRange [NUMERICAL]
# 	7 : Imc1 [NUMERICAL]
# 	7 : Id [NUMERICAL]
# 	6 : RobustMeanAbsoluteDeviation [NUMERICAL]
# 	6 : LowGrayLevelEmphasis [NUMERICAL]
# 	6 : DependenceVariance [NUMERICAL]
# 	5 : Uniformity [NUMERICAL]
# 	5 : SumEntropy [NUMERICAL]
# 	5 : LargeAreaEmphasis [NUMERICAL]
# 	5 : GrayLevelNonUniformity [NUMERICAL]
# 	5 : DependenceNonUniformityNormalized [NUMERICAL]
# 	5 : Autocorrelation [NUMERICAL]
# 	4 : RunVariance [NUMERICAL]
# 	4 : Mean [NUMERICAL]
# 	4 : LowGrayLevelRunEmphasis [NUMERICAL]
# 	4 : JointEnergy [NUMERICAL]
# 	4 : HighGrayLevelRunEmphasis [NUMERICAL]
# 	4 : GrayLevelNonUniformity.1 [NUMERICAL]
# 	4 : DependenceNonUniformity [NUMERICAL]
# 	3 : ZoneVariance [NUMERICAL]
# 	3 : RootMeanSquared [NUMERICAL]
# 	3 : GrayLevelVariance.2 [NUMERICAL]
# 	3 : GrayLevelNonUniformityNormalized [NUMERICAL]
# 	3 : Entropy [NUMERICAL]
# 	2 : ZonePercentage [NUMERICAL]
# 	2 : TotalEnergy [NUMERICAL]
# 	2 : SumSquares [NUMERICAL]
# 	2 : SizeZoneNonUniformity [NUMERICAL]
# 	2 : LongRunEmphasis [NUMERICAL]
# 	2 : LargeDependenceEmphasis [NUMERICAL]
# 	2 : Idm [NUMERICAL]
# 	2 : HighGrayLevelEmphasis [NUMERICAL]
# 	2 : GrayLevelVariance.1 [NUMERICAL]
# 	2 : ClusterTendency [NUMERICAL]
# 	2 : ClusterProminence [NUMERICAL]
# 	1 : SmallDependenceEmphasis [NUMERICAL]
# 	1 : ShortRunEmphasis [NUMERICAL]
# 	1 : RunPercentage [NUMERICAL]
# 	1 : RunLengthNonUniformityNormalized [NUMERICAL]
# 	1 : RunEntropy [NUMERICAL]
# 	1 : MeanAbsoluteDeviation [NUMERICAL]
# 	1 : GrayLevelVariance [NUMERICAL]
# 	1 : GrayLevelNonUniformityNormalized.1 [NUMERICAL]
#
# Attribute in nodes with depth <= 5:
# 	378 : Idn [NUMERICAL]
# 	157 : Idmn [NUMERICAL]
# 	155 : Coarseness [NUMERICAL]
# 	154 : LargeDependenceHighGrayLevelEmphasis [NUMERICAL]
# 	153 : LongRunHighGrayLevelEmphasis [NUMERICAL]
# 	121 : LargeAreaHighGrayLevelEmphasis [NUMERICAL]
# 	110 : Busyness [NUMERICAL]
# 	104 : Maximum [NUMERICAL]
# 	94 : Median [NUMERICAL]
# 	91 : 90Percentile [NUMERICAL]
# 	86 : GrayLevelNonUniformity.2 [NUMERICAL]
# 	85 : SmallDependenceLowGrayLevelEmphasis [NUMERICAL]
# 	79 : Contrast.1 [NUMERICAL]
# 	78 : ClusterShade [NUMERICAL]
# 	73 : Skewness [NUMERICAL]
# 	60 : Correlation [NUMERICAL]
# 	57 : DifferenceAverage [NUMERICAL]
# 	55 : SmallAreaLowGrayLevelEmphasis [NUMERICAL]
# 	55 : Contrast [NUMERICAL]
# 	54 : 10Percentile [NUMERICAL]
# 	45 : SmallDependenceHighGrayLevelEmphasis [NUMERICAL]
# 	41 : DifferenceVariance [NUMERICAL]
# 	40 : LowGrayLevelZoneEmphasis [NUMERICAL]
# 	39 : DifferenceEntropy [NUMERICAL]
# 	38 : Minimum [NUMERICAL]
# 	37 : SmallAreaHighGrayLevelEmphasis [NUMERICAL]
# 	37 : LargeDependenceLowGrayLevelEmphasis [NUMERICAL]
# 	31 : HighGrayLevelZoneEmphasis [NUMERICAL]
# 	30 : LargeAreaLowGrayLevelEmphasis [NUMERICAL]
# 	30 : Kurtosis [NUMERICAL]
# 	25 : LongRunLowGrayLevelEmphasis [NUMERICAL]
# 	25 : InverseVariance [NUMERICAL]
# 	24 : ZoneEntropy [NUMERICAL]
# 	23 : Range [NUMERICAL]
# 	23 : MCC [NUMERICAL]
# 	22 : DependenceEntropy [NUMERICAL]
# 	21 : ShortRunHighGrayLevelEmphasis [NUMERICAL]
# 	20 : MaximumProbability [NUMERICAL]
# 	20 : DependenceVariance [NUMERICAL]
# 	20 : Complexity [NUMERICAL]
# 	19 : SumAverage [NUMERICAL]
# 	18 : Strength [NUMERICAL]
# 	18 : SmallAreaEmphasis [NUMERICAL]
# 	17 : ShortRunLowGrayLevelEmphasis [NUMERICAL]
# 	17 : RobustMeanAbsoluteDeviation [NUMERICAL]
# 	15 : GrayLevelVariance.2 [NUMERICAL]
# 	14 : Imc2 [NUMERICAL]
# 	14 : Imc1 [NUMERICAL]
# 	14 : GrayLevelNonUniformityNormalized.1 [NUMERICAL]
# 	13 : InterquartileRange [NUMERICAL]
# 	13 : Id [NUMERICAL]
# 	13 : Autocorrelation [NUMERICAL]
# 	12 : SizeZoneNonUniformityNormalized [NUMERICAL]
# 	12 : LowGrayLevelRunEmphasis [NUMERICAL]
# 	12 : JointAverage [NUMERICAL]
# 	12 : HighGrayLevelRunEmphasis [NUMERICAL]
# 	12 : GrayLevelNonUniformity.1 [NUMERICAL]
# 	11 : Entropy [NUMERICAL]
# 	10 : SumEntropy [NUMERICAL]
# 	10 : JointEnergy [NUMERICAL]
# 	9 : Uniformity [NUMERICAL]
# 	8 : SmallDependenceEmphasis [NUMERICAL]
# 	7 : SizeZoneNonUniformity [NUMERICAL]
# 	7 : RunVariance [NUMERICAL]
# 	7 : RootMeanSquared [NUMERICAL]
# 	7 : Mean [NUMERICAL]
# 	7 : LowGrayLevelEmphasis [NUMERICAL]
# 	7 : GrayLevelNonUniformityNormalized [NUMERICAL]
# 	7 : GrayLevelNonUniformity [NUMERICAL]
# 	7 : DependenceNonUniformityNormalized [NUMERICAL]
# 	7 : ClusterTendency [NUMERICAL]
# 	6 : MeanAbsoluteDeviation [NUMERICAL]
# 	6 : LargeAreaEmphasis [NUMERICAL]
# 	6 : DependenceNonUniformity [NUMERICAL]
# 	5 : ZoneVariance [NUMERICAL]
# 	5 : RunLengthNonUniformityNormalized [NUMERICAL]
# 	5 : LargeDependenceEmphasis [NUMERICAL]
# 	5 : JointEntropy [NUMERICAL]
# 	5 : Idm [NUMERICAL]
# 	5 : HighGrayLevelEmphasis [NUMERICAL]
# 	4 : ZonePercentage [NUMERICAL]
# 	4 : RunLengthNonUniformity [NUMERICAL]
# 	4 : RunEntropy [NUMERICAL]
# 	4 : LongRunEmphasis [NUMERICAL]
# 	4 : ClusterProminence [NUMERICAL]
# 	3 : TotalEnergy [NUMERICAL]
# 	3 : SumSquares [NUMERICAL]
# 	3 : GrayLevelVariance.1 [NUMERICAL]
# 	3 : GrayLevelVariance [NUMERICAL]
# 	3 : Energy [NUMERICAL]
# 	2 : RunPercentage [NUMERICAL]
# 	1 : Variance [NUMERICAL]
# 	1 : ShortRunEmphasis [NUMERICAL]
#
# Condition type in nodes:
# 	3233 : HigherCondition
# Condition type in nodes with depth <= 0:
# 	123 : HigherCondition
# Condition type in nodes with depth <= 1:
# 	369 : HigherCondition
# Condition type in nodes with depth <= 2:
# 	840 : HigherCondition
# Condition type in nodes with depth <= 3:
# 	1705 : HigherCondition
# Condition type in nodes with depth <= 5:
# 	3233 : HigherCondition
#
# Training logs:
# Number of iteration to final model: 123
# 	Iter:1 train-loss:1.248717 valid-loss:1.253613  train-accuracy:0.916335 valid-accuracy:0.902506
# 	Iter:2 train-loss:1.134780 valid-loss:1.143249  train-accuracy:0.918925 valid-accuracy:0.910453
# 	Iter:3 train-loss:1.037630 valid-loss:1.048155  train-accuracy:0.923021 valid-accuracy:0.914893
# 	Iter:4 train-loss:0.951344 valid-loss:0.965968  train-accuracy:0.926455 valid-accuracy:0.917921
# 	Iter:5 train-loss:0.883046 valid-loss:0.898935  train-accuracy:0.924871 valid-accuracy:0.917450
# 	Iter:6 train-loss:0.815432 valid-loss:0.834512  train-accuracy:0.932223 valid-accuracy:0.919153
# 	Iter:16 train-loss:0.460989 valid-loss:0.510757  train-accuracy:0.945362 valid-accuracy:0.927663
# 	Iter:26 train-loss:0.310256 valid-loss:0.385878  train-accuracy:0.960218 valid-accuracy:0.937687
# 	Iter:36 train-loss:0.231932 valid-loss:0.328113  train-accuracy:0.970474 valid-accuracy:0.946008
# 	Iter:46 train-loss:0.184290 valid-loss:0.306176  train-accuracy:0.977069 valid-accuracy:0.953761
# 	Iter:56 train-loss:0.157182 valid-loss:0.294843  train-accuracy:0.981997 valid-accuracy:0.954518
# 	Iter:66 train-loss:0.133699 valid-loss:0.281770  train-accuracy:0.987414 valid-accuracy:0.955275
# 	Iter:76 train-loss:0.115482 valid-loss:0.275208  train-accuracy:0.989739 valid-accuracy:0.954237
# 	Iter:86 train-loss:0.100992 valid-loss:0.269964  train-accuracy:0.991576 valid-accuracy:0.954804
# 	Iter:96 train-loss:0.089475 valid-loss:0.263852  train-accuracy:0.993751 valid-accuracy:0.955940
# 	Iter:106 train-loss:0.080668 valid-loss:0.263448  train-accuracy:0.994350 valid-accuracy:0.956129
# 	Iter:116 train-loss:0.072552 valid-loss:0.259660  train-accuracy:0.995089 valid-accuracy:0.956507
# 	Iter:126 train-loss:0.065679 valid-loss:0.259468  train-accuracy:0.995488 valid-accuracy:0.954334
# 	Iter:136 train-loss:0.059458 valid-loss:0.258395  train-accuracy:0.996087 valid-accuracy:0.954712
# 	Iter:146 train-loss:0.054721 valid-loss:0.261055  train-accuracy:0.996606 valid-accuracy:0.956037

# %%
# Model features
model.make_inspector().features()
# Out:
# ["10Percentile" (1; #0),
#  "90Percentile" (1; #1),
#  "Autocorrelation" (1; #2),
#  "Busyness" (1; #3),
#  "ClusterProminence" (1; #4),
#  "ClusterShade" (1; #5),
#  "ClusterTendency" (1; #6),
#  "Coarseness" (1; #7),
#  "Complexity" (1; #8),
#  "Contrast" (1; #9),
#  "Contrast.1" (1; #10),
#  "Correlation" (1; #11),
#  "DependenceEntropy" (1; #12),
#  "DependenceNonUniformity" (1; #13),
#  "DependenceNonUniformityNormalized" (1; #14),
#  "DependenceVariance" (1; #15),
#  "DifferenceAverage" (1; #16),
#  "DifferenceEntropy" (1; #17),
#  "DifferenceVariance" (1; #18),
#  "Energy" (1; #19),
#  "Entropy" (1; #20),
#  "GrayLevelNonUniformity" (1; #21),
#  "GrayLevelNonUniformity.1" (1; #22),
#  "GrayLevelNonUniformity.2" (1; #23),
#  "GrayLevelNonUniformityNormalized" (1; #24),
#  "GrayLevelNonUniformityNormalized.1" (1; #25),
#  "GrayLevelVariance" (1; #26),
#  "GrayLevelVariance.1" (1; #27),
#  "GrayLevelVariance.2" (1; #28),
#  "HighGrayLevelEmphasis" (1; #29),
#  "HighGrayLevelRunEmphasis" (1; #30),
#  "HighGrayLevelZoneEmphasis" (1; #31),
#  "Id" (1; #32),
#  "Idm" (1; #33),
#  "Idmn" (1; #34),
#  "Idn" (1; #35),
#  "Imc1" (1; #36),
#  "Imc2" (1; #37),
#  "InterquartileRange" (1; #38),
#  "InverseVariance" (1; #39),
#  "JointAverage" (1; #40),
#  "JointEnergy" (1; #41),
#  "JointEntropy" (1; #42),
#  "Kurtosis" (1; #43),
#  "LargeAreaEmphasis" (1; #44),
#  "LargeAreaHighGrayLevelEmphasis" (1; #45),
#  "LargeAreaLowGrayLevelEmphasis" (1; #46),
#  "LargeDependenceEmphasis" (1; #47),
#  "LargeDependenceHighGrayLevelEmphasis" (1; #48),
#  "LargeDependenceLowGrayLevelEmphasis" (1; #49),
#  "LongRunEmphasis" (1; #50),
#  "LongRunHighGrayLevelEmphasis" (1; #51),
#  "LongRunLowGrayLevelEmphasis" (1; #52),
#  "LowGrayLevelEmphasis" (1; #53),
#  "LowGrayLevelRunEmphasis" (1; #54),
#  "LowGrayLevelZoneEmphasis" (1; #55),
#  "MCC" (1; #56),
#  "Maximum" (1; #57),
#  "MaximumProbability" (1; #58),
#  "Mean" (1; #59),
#  "MeanAbsoluteDeviation" (1; #60),
#  "Median" (1; #61),
#  "Minimum" (1; #62),
#  "Range" (1; #63),
#  "RobustMeanAbsoluteDeviation" (1; #64),
#  "RootMeanSquared" (1; #65),
#  "RunEntropy" (1; #66),
#  "RunLengthNonUniformity" (1; #67),
#  "RunLengthNonUniformityNormalized" (1; #68),
#  "RunPercentage" (1; #69),
#  "RunVariance" (1; #70),
#  "ShortRunEmphasis" (1; #71),
#  "ShortRunHighGrayLevelEmphasis" (1; #72),
#  "ShortRunLowGrayLevelEmphasis" (1; #73),
#  "SizeZoneNonUniformity" (1; #74),
#  "SizeZoneNonUniformityNormalized" (1; #75),
#  "Skewness" (1; #76),
#  "SmallAreaEmphasis" (1; #77),
#  "SmallAreaHighGrayLevelEmphasis" (1; #78),
#  "SmallAreaLowGrayLevelEmphasis" (1; #79),
#  "SmallDependenceEmphasis" (1; #80),
#  "SmallDependenceHighGrayLevelEmphasis" (1; #81),
#  "SmallDependenceLowGrayLevelEmphasis" (1; #82),
#  "Strength" (1; #83),
#  "SumAverage" (1; #84),
#  "SumEntropy" (1; #85),
#  "SumSquares" (1; #86),
#  "TotalEnergy" (1; #87),
#  "Uniformity" (1; #88),
#  "Variance" (1; #89),
#  "ZoneEntropy" (1; #90),
#  "ZonePercentage" (1; #91),
#  "ZoneVariance" (1; #92)]

# %%
# Feature importance
model.make_inspector().variable_importances()
# Out:
# {'INV_MEAN_MIN_DEPTH': [("Idn" (1; #35), 0.23804433122296687),
#   ("LongRunHighGrayLevelEmphasis" (1; #51), 0.23802799031533298),
#   ("LargeDependenceHighGrayLevelEmphasis" (1; #48), 0.21865308807251074),
#   ("Coarseness" (1; #7), 0.21490546675706373),
#   ("Maximum" (1; #57), 0.18771467437668435),
#   ("Correlation" (1; #11), 0.1862841794812591),
#   ("GrayLevelNonUniformity.2" (1; #23), 0.18522826201419315),
#   ("Idmn" (1; #34), 0.18416527915493713),
#   ("Median" (1; #61), 0.18165048033855274),
#   ("SmallAreaLowGrayLevelEmphasis" (1; #79), 0.18016063485819364),
#   ("LargeAreaHighGrayLevelEmphasis" (1; #45), 0.18014619067919052),
#   ("Busyness" (1; #3), 0.17980758241586295),
#   ("ClusterShade" (1; #5), 0.1791775330470612),
#   ("10Percentile" (1; #0), 0.17914731494188652),
#   ("90Percentile" (1; #1), 0.1782634796036804),
#   ("SmallDependenceLowGrayLevelEmphasis" (1; #82), 0.17780307912315166),
#   ("Skewness" (1; #76), 0.1771373986063812),
#   ("Contrast.1" (1; #10), 0.17653449881088848),
#   ("SmallDependenceHighGrayLevelEmphasis" (1; #81), 0.17576488284502562),
#   ("DifferenceAverage" (1; #16), 0.1750504206830832),
#   ("HighGrayLevelZoneEmphasis" (1; #31), 0.17489441844478507),
#   ("SmallAreaHighGrayLevelEmphasis" (1; #78), 0.1746789671871657),
#   ("Contrast" (1; #9), 0.17425125866935828),
#   ("DifferenceEntropy" (1; #17), 0.17423903049256584),
#   ("LowGrayLevelZoneEmphasis" (1; #55), 0.17408175502339288),
#   ("DifferenceVariance" (1; #18), 0.17350230913090062),
#   ("LargeAreaLowGrayLevelEmphasis" (1; #46), 0.17312864808356326),
#   ("LongRunLowGrayLevelEmphasis" (1; #52), 0.17280567044623235),
#   ("Autocorrelation" (1; #2), 0.17276536222402838),
#   ("LargeDependenceLowGrayLevelEmphasis" (1; #49), 0.17262589667767955),
#   ("Range" (1; #63), 0.17261277747715906),
#   ("Minimum" (1; #62), 0.17257420869381132),
#   ("ShortRunHighGrayLevelEmphasis" (1; #72), 0.17236177875109066),
#   ("Kurtosis" (1; #43), 0.1723433490495809),
#   ("SumAverage" (1; #84), 0.17216476816831783),
#   ("ZoneEntropy" (1; #90), 0.17214315101160543),
#   ("SmallAreaEmphasis" (1; #77), 0.17210003467836618),
#   ("Imc2" (1; #37), 0.1720388589911843),
#   ("ShortRunLowGrayLevelEmphasis" (1; #73), 0.1719739027583757),
#   ("Complexity" (1; #8), 0.17193196028019278),
#   ("DependenceEntropy" (1; #12), 0.1719058532341013),
#   ("JointAverage" (1; #40), 0.17190383098452575),
#   ("InverseVariance" (1; #39), 0.1718688080326043),
#   ("MaximumProbability" (1; #58), 0.17176599910697407),
#   ("GrayLevelNonUniformity.1" (1; #22), 0.1716496800544687),
#   ("MCC" (1; #56), 0.17157539851006795),
#   ("Id" (1; #32), 0.1715516138141982),
#   ("Strength" (1; #83), 0.1715416440933459),
#   ("GrayLevelNonUniformity" (1; #21), 0.17149710246029679),
#   ("GrayLevelNonUniformityNormalized" (1; #24), 0.1714824929402302),
#   ("Uniformity" (1; #88), 0.17147915439563366),
#   ("Imc1" (1; #36), 0.17144619110628537),
#   ("Mean" (1; #59), 0.17144092500915256),
#   ("LowGrayLevelEmphasis" (1; #53), 0.1713712872444717),
#   ("RobustMeanAbsoluteDeviation" (1; #64), 0.17135614471238597),
#   ("SumEntropy" (1; #85), 0.1713450849580835),
#   ("InterquartileRange" (1; #38), 0.1713323878283733),
#   ("SizeZoneNonUniformityNormalized" (1; #75), 0.17129128158381746),
#   ("DependenceVariance" (1; #15), 0.1712760231441832),
#   ("ZoneVariance" (1; #92), 0.17125058065691023),
#   ("LowGrayLevelRunEmphasis" (1; #54), 0.171220761289597),
#   ("LargeAreaEmphasis" (1; #44), 0.17117687863513553),
#   ("HighGrayLevelRunEmphasis" (1; #30), 0.17114472612574363),
#   ("RootMeanSquared" (1; #65), 0.17111153664124742),
#   ("Entropy" (1; #20), 0.17109303078904992),
#   ("GrayLevelVariance.2" (1; #28), 0.17109104399017375),
#   ("RunVariance" (1; #70), 0.17107539058066956),
#   ("JointEnergy" (1; #41), 0.17105245342855518),
#   ("DependenceNonUniformityNormalized" (1; #14), 0.1710365384604405),
#   ("ZonePercentage" (1; #91), 0.17101762759003303),
#   ("GrayLevelNonUniformityNormalized.1" (1; #25), 0.17100553266266524),
#   ("SizeZoneNonUniformity" (1; #74), 0.1709953914318868),
#   ("DependenceNonUniformity" (1; #13), 0.17098840527734094),
#   ("SumSquares" (1; #86), 0.1709833677274308),
#   ("SmallDependenceEmphasis" (1; #80), 0.17096067456094663),
#   ("ClusterTendency" (1; #6), 0.17095845455033246),
#   ("GrayLevelVariance" (1; #26), 0.17094372440247227),
#   ("GrayLevelVariance.1" (1; #27), 0.17093913180098683),
#   ("LargeDependenceEmphasis" (1; #47), 0.1709258352782048),
#   ("TotalEnergy" (1; #87), 0.17089070482028085),
#   ("MeanAbsoluteDeviation" (1; #60), 0.17088923624899),
#   ("ClusterProminence" (1; #4), 0.17086846429816424),
#   ("HighGrayLevelEmphasis" (1; #29), 0.17085978277626288),
#   ("LongRunEmphasis" (1; #50), 0.17085578944144822),
#   ("Idm" (1; #33), 0.17084844250406941),
#   ("RunEntropy" (1; #66), 0.17082608800414661),
#   ("JointEntropy" (1; #42), 0.17081249201579438),
#   ("RunLengthNonUniformityNormalized" (1; #68), 0.17080204559618417),
#   ("RunLengthNonUniformity" (1; #67), 0.17079767131537882),
#   ("RunPercentage" (1; #69), 0.17078480728644108),
#   ("ShortRunEmphasis" (1; #71), 0.17077803230541067),
#   ("Energy" (1; #19), 0.17077431691014144),
#   ("Variance" (1; #89), 0.1707377322796137)],
#  'NUM_AS_ROOT': [("LongRunHighGrayLevelEmphasis" (1; #51), 39.0),
#   ("LargeDependenceHighGrayLevelEmphasis" (1; #48), 20.0),
#   ("Coarseness" (1; #7), 18.0),
#   ("Correlation" (1; #11), 9.0),
#   ("Idn" (1; #35), 6.0),
#   ("10Percentile" (1; #0), 5.0),
#   ("GrayLevelNonUniformity.2" (1; #23), 5.0),
#   ("Maximum" (1; #57), 5.0),
#   ("SmallAreaLowGrayLevelEmphasis" (1; #79), 5.0),
#   ("Median" (1; #61), 3.0),
#   ("Idmn" (1; #34), 2.0),
#   ("90Percentile" (1; #1), 1.0),
#   ("Autocorrelation" (1; #2), 1.0),
#   ("Busyness" (1; #3), 1.0),
#   ("DifferenceEntropy" (1; #17), 1.0),
#   ("LowGrayLevelZoneEmphasis" (1; #55), 1.0),
#   ("SmallDependenceLowGrayLevelEmphasis" (1; #82), 1.0)],
#  'SUM_SCORE': [("LongRunHighGrayLevelEmphasis" (1; #51), 18948.833214586062),
#   ("Idn" (1; #35), 2849.0132945575997),
#   ("LargeDependenceHighGrayLevelEmphasis" (1; #48), 2397.5780178972495),
#   ("Coarseness" (1; #7), 1140.6400609459456),
#   ("GrayLevelNonUniformity.2" (1; #23), 1014.4316810254869),
#   ("LargeAreaHighGrayLevelEmphasis" (1; #45), 939.1579175276883),
#   ("Maximum" (1; #57), 694.1249972017646),
#   ("Busyness" (1; #3), 637.88767896456),
#   ("Skewness" (1; #76), 478.1363454742579),
#   ("Median" (1; #61), 473.48480421493167),
#   ("90Percentile" (1; #1), 442.011160925508),
#   ("Idmn" (1; #34), 434.4580620447808),
#   ("Contrast.1" (1; #10), 329.6298493803924),
#   ("SmallDependenceLowGrayLevelEmphasis" (1; #82), 227.13441931537724),
#   ("DifferenceAverage" (1; #16), 184.25261359458045),
#   ("Contrast" (1; #9), 161.08287497974732),
#   ("DifferenceEntropy" (1; #17), 160.74487502289273),
#   ("SmallDependenceHighGrayLevelEmphasis" (1; #81), 141.19795565974795),
#   ("Autocorrelation" (1; #2), 140.66435388184163),
#   ("SmallAreaHighGrayLevelEmphasis" (1; #78), 139.33934428682053),
#   ("ClusterShade" (1; #5), 138.0205229453559),
#   ("LargeDependenceLowGrayLevelEmphasis" (1; #49), 131.71572181257793),
#   ("DifferenceVariance" (1; #18), 131.3790578160321),
#   ("Minimum" (1; #62), 114.02472815828251),
#   ("SmallAreaLowGrayLevelEmphasis" (1; #79), 108.07715238184402),
#   ("LargeAreaLowGrayLevelEmphasis" (1; #46), 92.44455446122181),
#   ("10Percentile" (1; #0), 89.07596469841755),
#   ("Correlation" (1; #11), 71.2282603744824),
#   ("LowGrayLevelZoneEmphasis" (1; #55), 70.97986331838086),
#   ("Kurtosis" (1; #43), 62.52138747008627),
#   ("Id" (1; #32), 62.49866811944319),
#   ("SumAverage" (1; #84), 61.88591340415335),
#   ("MCC" (1; #56), 58.35132511201313),
#   ("MaximumProbability" (1; #58), 46.83899703425519),
#   ("InverseVariance" (1; #39), 44.231589145172094),
#   ("HighGrayLevelZoneEmphasis" (1; #31), 43.16912497308553),
#   ("DependenceEntropy" (1; #12), 41.14679022061831),
#   ("LowGrayLevelRunEmphasis" (1; #54), 39.47804112764903),
#   ("GrayLevelNonUniformity.1" (1; #22), 39.096939669932446),
#   ("SizeZoneNonUniformityNormalized" (1; #75), 35.819949640287035),
#   ("ShortRunHighGrayLevelEmphasis" (1; #72), 35.56115024343593),
#   ("GrayLevelNonUniformityNormalized.1" (1; #25), 33.98896634116757),
#   ("LongRunLowGrayLevelEmphasis" (1; #52), 32.24853428683531),
#   ("DependenceVariance" (1; #15), 31.15914622431602),
#   ("SumEntropy" (1; #85), 29.661755442637897),
#   ("HighGrayLevelRunEmphasis" (1; #30), 25.749060373839413),
#   ("DependenceNonUniformityNormalized" (1; #14), 23.717596765002476),
#   ("ZonePercentage" (1; #91), 23.376749250778218),
#   ("Complexity" (1; #8), 23.143890962376307),
#   ("Range" (1; #63), 22.82146980058498),
#   ("Strength" (1; #83), 22.393256662018214),
#   ("Imc2" (1; #37), 22.16636426753184),
#   ("SmallAreaEmphasis" (1; #77), 21.389119589485887),
#   ("Uniformity" (1; #88), 20.283622077635282),
#   ("HighGrayLevelEmphasis" (1; #29), 19.75841120442178),
#   ("LowGrayLevelEmphasis" (1; #53), 17.461790617421176),
#   ("ZoneEntropy" (1; #90), 17.172461064064034),
#   ("Imc1" (1; #36), 15.735787170884775),
#   ("JointAverage" (1; #40), 15.659898135655817),
#   ("DependenceNonUniformity" (1; #13), 15.583688564474553),
#   ("RobustMeanAbsoluteDeviation" (1; #64), 15.499312265831126),
#   ("GrayLevelNonUniformityNormalized" (1; #24), 15.073915255186492),
#   ("ShortRunLowGrayLevelEmphasis" (1; #73), 14.760234166712529),
#   ("RootMeanSquared" (1; #65), 14.484125063642328),
#   ("ClusterProminence" (1; #4), 14.450071941673858),
#   ("GrayLevelVariance.2" (1; #28), 14.183844078845942),
#   ("GrayLevelNonUniformity" (1; #21), 13.17039128764744),
#   ("SmallDependenceEmphasis" (1; #80), 11.64056836021669),
#   ("RunVariance" (1; #70), 10.632898339256446),
#   ("Idm" (1; #33), 9.742037226249533),
#   ("Entropy" (1; #20), 9.380080394660874),
#   ("ClusterTendency" (1; #6), 8.80673932625585),
#   ("InterquartileRange" (1; #38), 8.264409367558704),
#   ("ShortRunEmphasis" (1; #71), 7.649264815122394),
#   ("SumSquares" (1; #86), 7.474636974687987),
#   ("Mean" (1; #59), 7.1391378552006),
#   ("LargeDependenceEmphasis" (1; #47), 6.741827248668157),
#   ("JointEnergy" (1; #41), 5.598546844775226),
#   ("LargeAreaEmphasis" (1; #44), 5.042354934108139),
#   ("RunLengthNonUniformityNormalized" (1; #68), 5.023752696397017),
#   ("MeanAbsoluteDeviation" (1; #60), 4.447102860953123),
#   ("SizeZoneNonUniformity" (1; #74), 4.166184039452086),
#   ("GrayLevelVariance" (1; #26), 4.032536434552897),
#   ("RunEntropy" (1; #66), 3.99241500898298),
#   ("TotalEnergy" (1; #87), 3.075535786206543),
#   ("LongRunEmphasis" (1; #50), 2.810249861881891),
#   ("ZoneVariance" (1; #92), 2.7385784970758245),
#   ("JointEntropy" (1; #42), 2.245136593114643),
#   ("GrayLevelVariance.1" (1; #27), 1.5576948566209532),
#   ("RunLengthNonUniformity" (1; #67), 1.121395386543866),
#   ("RunPercentage" (1; #69), 0.9130938386924211),
#   ("Variance" (1; #89), 0.7478032754435495),
#   ("Energy" (1; #19), 0.30439981055745663)],
#  'NUM_NODES': [("Idn" (1; #35), 378.0),
#   ("Idmn" (1; #34), 157.0),
#   ("Coarseness" (1; #7), 155.0),
#   ("LargeDependenceHighGrayLevelEmphasis" (1; #48), 154.0),
#   ("LongRunHighGrayLevelEmphasis" (1; #51), 153.0),
#   ("LargeAreaHighGrayLevelEmphasis" (1; #45), 121.0),
#   ("Busyness" (1; #3), 110.0),
#   ("Maximum" (1; #57), 104.0),
#   ("Median" (1; #61), 94.0),
#   ("90Percentile" (1; #1), 91.0),
#   ("GrayLevelNonUniformity.2" (1; #23), 86.0),
#   ("SmallDependenceLowGrayLevelEmphasis" (1; #82), 85.0),
#   ("Contrast.1" (1; #10), 79.0),
#   ("ClusterShade" (1; #5), 78.0),
#   ("Skewness" (1; #76), 73.0),
#   ("Correlation" (1; #11), 60.0),
#   ("DifferenceAverage" (1; #16), 57.0),
#   ("Contrast" (1; #9), 55.0),
#   ("SmallAreaLowGrayLevelEmphasis" (1; #79), 55.0),
#   ("10Percentile" (1; #0), 54.0),
#   ("SmallDependenceHighGrayLevelEmphasis" (1; #81), 45.0),
#   ("DifferenceVariance" (1; #18), 41.0),
#   ("LowGrayLevelZoneEmphasis" (1; #55), 40.0),
#   ("DifferenceEntropy" (1; #17), 39.0),
#   ("Minimum" (1; #62), 38.0),
#   ("LargeDependenceLowGrayLevelEmphasis" (1; #49), 37.0),
#   ("SmallAreaHighGrayLevelEmphasis" (1; #78), 37.0),
#   ("HighGrayLevelZoneEmphasis" (1; #31), 31.0),
#   ("Kurtosis" (1; #43), 30.0),
#   ("LargeAreaLowGrayLevelEmphasis" (1; #46), 30.0),
#   ("InverseVariance" (1; #39), 25.0),
#   ("LongRunLowGrayLevelEmphasis" (1; #52), 25.0),
#   ("ZoneEntropy" (1; #90), 24.0),
#   ("MCC" (1; #56), 23.0),
#   ("Range" (1; #63), 23.0),
#   ("DependenceEntropy" (1; #12), 22.0),
#   ("ShortRunHighGrayLevelEmphasis" (1; #72), 21.0),
#   ("Complexity" (1; #8), 20.0),
#   ("DependenceVariance" (1; #15), 20.0),
#   ("MaximumProbability" (1; #58), 20.0),
#   ("SumAverage" (1; #84), 19.0),
#   ("SmallAreaEmphasis" (1; #77), 18.0),
#   ("Strength" (1; #83), 18.0),
#   ("RobustMeanAbsoluteDeviation" (1; #64), 17.0),
#   ("ShortRunLowGrayLevelEmphasis" (1; #73), 17.0),
#   ("GrayLevelVariance.2" (1; #28), 15.0),
#   ("GrayLevelNonUniformityNormalized.1" (1; #25), 14.0),
#   ("Imc1" (1; #36), 14.0),
#   ("Imc2" (1; #37), 14.0),
#   ("Autocorrelation" (1; #2), 13.0),
#   ("Id" (1; #32), 13.0),
#   ("InterquartileRange" (1; #38), 13.0),
#   ("GrayLevelNonUniformity.1" (1; #22), 12.0),
#   ("HighGrayLevelRunEmphasis" (1; #30), 12.0),
#   ("JointAverage" (1; #40), 12.0),
#   ("LowGrayLevelRunEmphasis" (1; #54), 12.0),
#   ("SizeZoneNonUniformityNormalized" (1; #75), 12.0),
#   ("Entropy" (1; #20), 11.0),
#   ("JointEnergy" (1; #41), 10.0),
#   ("SumEntropy" (1; #85), 10.0),
#   ("Uniformity" (1; #88), 9.0),
#   ("SmallDependenceEmphasis" (1; #80), 8.0),
#   ("ClusterTendency" (1; #6), 7.0),
#   ("DependenceNonUniformityNormalized" (1; #14), 7.0),
#   ("GrayLevelNonUniformity" (1; #21), 7.0),
#   ("GrayLevelNonUniformityNormalized" (1; #24), 7.0),
#   ("LowGrayLevelEmphasis" (1; #53), 7.0),
#   ("Mean" (1; #59), 7.0),
#   ("RootMeanSquared" (1; #65), 7.0),
#   ("RunVariance" (1; #70), 7.0),
#   ("SizeZoneNonUniformity" (1; #74), 7.0),
#   ("DependenceNonUniformity" (1; #13), 6.0),
#   ("LargeAreaEmphasis" (1; #44), 6.0),
#   ("MeanAbsoluteDeviation" (1; #60), 6.0),
#   ("HighGrayLevelEmphasis" (1; #29), 5.0),
#   ("Idm" (1; #33), 5.0),
#   ("JointEntropy" (1; #42), 5.0),
#   ("LargeDependenceEmphasis" (1; #47), 5.0),
#   ("RunLengthNonUniformityNormalized" (1; #68), 5.0),
#   ("ZoneVariance" (1; #92), 5.0),
#   ("ClusterProminence" (1; #4), 4.0),
#   ("LongRunEmphasis" (1; #50), 4.0),
#   ("RunEntropy" (1; #66), 4.0),
#   ("RunLengthNonUniformity" (1; #67), 4.0),
#   ("ZonePercentage" (1; #91), 4.0),
#   ("Energy" (1; #19), 3.0),
#   ("GrayLevelVariance" (1; #26), 3.0),
#   ("GrayLevelVariance.1" (1; #27), 3.0),
#   ("SumSquares" (1; #86), 3.0),
#   ("TotalEnergy" (1; #87), 3.0),
#   ("RunPercentage" (1; #69), 2.0),
#   ("ShortRunEmphasis" (1; #71), 1.0),
#   ("Variance" (1; #89), 1.0)]}

# %%
# Model self evaluation
model.make_inspector().evaluation()
# Out:
# Evaluation(num_examples=None, accuracy=0.9541444778442383, loss=0.2581702470779419, rmse=None, ndcg=None, aucs=None, auuc=None, qini=None)

# %%
logs = model.make_inspector().training_logs()

plt.figure(figsize=(12, 4))
plt.subplot(1, 2, 1)
plt.plot([log.num_trees for log in logs], [log.evaluation.accuracy for log in logs])
plt.xlabel("Number of trees")
plt.ylabel("Accuracy (out-of-bag)")
plt.subplot(1, 2, 2)
plt.plot([log.num_trees for log in logs], [log.evaluation.loss for log in logs])
plt.xlabel("Number of trees")
plt.ylabel("Logloss (out-of-bag)")
plt.show()

# %% [markdown]
# Calculate the score of our hold-out validation dataset

# %%
predictions = model.predict(val_ds)
y_true      = validation_data["label"]

from sklearn.metrics import roc_auc_score
ROC_AUC = roc_auc_score(y_true, predictions)
print("The ROC AUC score is %.5f" % ROC_AUC )
# Out:
# 1/5 [=====>........................] - ETA: 0s
# 4/5 [=======================>......] - ETA: 0s
# 5/5 [==============================] - 0s 19ms/step
# The ROC AUC score is 0.99870

# %%
# Compute binary classification metrics with sklearn
import numpy as np
from sklearn.metrics import (
    accuracy_score,
    precision_score,
    recall_score,
    f1_score,
    roc_auc_score,
    average_precision_score,
    confusion_matrix,
    classification_report,
    matthews_corrcoef,
    log_loss,
    brier_score_loss,
)

# Get predictions (probabilities or class labels)
preds = model.predict(test_ds)
# If model outputs probabilities, convert to labels by threshold 0.5
if preds.ndim == 2:
    # For TFDF classification, preds may be class probabilities with shape (N, 2)
    if preds.shape[1] == 2:
        pos_probs = preds[:, 1]
    else:
        # If single-probability column (positive class)
        pos_probs = preds[:, -1]
    y_pred = (pos_probs >= 0.5).astype(int)
else:
    # Already class labels
    y_pred = preds.astype(int)
    pos_probs = None

# Ground truth labels (must be 0/1 integers)
y_true = test_data["label"].astype(int).to_numpy()

# Core metrics
metrics = {}
metrics["accuracy"] = accuracy_score(y_true, y_pred)
metrics["precision"] = precision_score(y_true, y_pred, zero_division=0)
metrics["recall"] = recall_score(y_true, y_pred, zero_division=0)
metrics["f1"] = f1_score(y_true, y_pred, zero_division=0)
metrics["mcc"] = matthews_corrcoef(y_true, y_pred)

# Probabilistic metrics (only if we have probabilities)
if pos_probs is not None:
    metrics["roc_auc"] = roc_auc_score(y_true, pos_probs)
    metrics["pr_auc"] = average_precision_score(y_true, pos_probs)
    metrics["log_loss"] = log_loss(y_true, pos_probs, labels=[0,1])
    metrics["brier_score"] = brier_score_loss(y_true, pos_probs)

# Confusion matrix and detailed report
cm = confusion_matrix(y_true, y_pred, labels=[0,1])
report = classification_report(y_true, y_pred, digits=4)

print("Sklearn binary metrics:")
for k, v in metrics.items():
    print(f"{k}: {v:.4f}")
print("\nConfusion matrix:\n", cm)
print("\nClassification report:\n", report)
# Out:
# 1/9 [==>...........................] - ETA: 1s
# 4/9 [============>.................] - ETA: 0s
# 7/9 [======================>.......] - ETA: 0s
# 9/9 [==============================] - 0s 23ms/step
# Sklearn binary metrics:
# accuracy: 0.9629
# precision: 0.7621
# recall: 0.9105
# f1: 0.8297
# mcc: 0.8131
# roc_auc: 0.9751
# pr_auc: 0.9129
# log_loss: 0.1237
# brier_score: 0.0307
#
# Confusion matrix:
#  [[7760  251]
#  [  79  804]]
#
# Classification report:
#                precision    recall  f1-score   support
#
#            0     0.9899    0.9687    0.9792      8011
#            1     0.7621    0.9105    0.8297       883
#
#     accuracy                         0.9629      8894
#    macro avg     0.8760    0.9396    0.9045      8894
# weighted avg     0.9673    0.9629    0.9643      8894
