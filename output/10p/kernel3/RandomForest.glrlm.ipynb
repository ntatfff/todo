# %%
# Import packages and modules
import numpy  as np
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow_decision_forests as tfdf

from sklearn.model_selection import train_test_split
# Out:
# 2026-09-11 03:38:27.482088: I tensorflow/core/util/port.cc:113] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2026-09-11 03:38:27.835612: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2026-09-11 03:38:32.276583: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
# Check the version of TensorFlow Decision Forests
print("Found TensorFlow Decision Forests v" + tfdf.__version__)
# Out:
# Found TensorFlow Decision Forests v1.9.1

# %%
datasetPath = "dataset/10p/all/kernel3/"

# %%
# Parameters
datasetPath = "dataset/10p/glrlm/kernel3/"

# %%
# train/validation/test = 70/10/20
train_data = pd.read_csv(f"{datasetPath}dataset.train.csv")
validation_data = pd.read_csv(f"{datasetPath}dataset.validation.csv")
test_data = pd.read_csv(f"{datasetPath}dataset.test.csv")

# %%
from sklearn.utils.class_weight import compute_class_weight

# tinh class weight tren tap train
classes = np.array([0, 1])
weights = compute_class_weight(class_weight="balanced", classes=classes, y=train_data["label"])
class_weight = {0: weights[0], 1: weights[1]}

# gan sample_weight cho tung dong
train_data["sample_weight"] = train_data["label"].map(class_weight)
validation_data["sample_weight"] = validation_data["label"].map(class_weight)
test_data["sample_weight"] = test_data["label"].map(class_weight)

# Convert the dataset into a TensorFlow dataset.
train_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    train_data, label="label", weight="sample_weight"
)         
val_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    validation_data, label="label", weight="sample_weight"
)
test_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    test_data, label="label", weight="sample_weight"
)
# Out:
# 2026-09-11 03:38:44.508414: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:984] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2026-09-11 03:38:44.509968: W tensorflow/core/common_runtime/gpu/gpu_device.cc:2251] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...

# %%
import keras

# %%
# %%time

# Train a Random Forest model.
model = tfdf.keras.RandomForestModel()

# Add evaluation metrics
model.compile(
    metrics=["accuracy"]
)
model.fit(x=train_ds)

# # Train a Gradient Boosted Trees model.
# model = tfdf.keras.GradientBoostedTreesModel(num_trees=1500)
# model.fit(train_ds)
# Out:
# Use /tmp/tmp_iwvqidw as temporary training directory
# Reading training dataset...
# Training dataset read in 0:00:04.605179. Found 29597 examples.
# Training model...
# [INFO 26-09-11 03:38:51.2078 UTC kernel.cc:1233] Loading model from path /tmp/tmp_iwvqidw/model/ with prefix cefc04421e5a47cc
# Model trained in 0:00:02.276275
# Compiling model...
# [INFO 26-09-11 03:38:51.5067 UTC decision_forest.cc:734] Model loaded with 300 root(s), 256498 node(s), and 16 input feature(s).
# [INFO 26-09-11 03:38:51.5067 UTC abstract_model.cc:1362] Engine "RandomForestOptPred" built
# [INFO 26-09-11 03:38:51.5067 UTC kernel.cc:1061] Use fast generic engine
# Model compiled.
# CPU times: user 26.9 s, sys: 466 ms, total: 27.3 s
# Wall time: 9.92 s

# %%
# Evaluate the model
evaluate = model.evaluate(val_ds, return_dict=True)
print()

for name, value in evaluate.items():
    print(f"{name}: {value:.4f}")
# Out:
# WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 1/5 [=====>........................] - ETA: 11s - loss: 0.0000e+00 - accuracy: 0.9900
# 4/5 [=======================>......] - ETA: 0s - loss: 0.0000e+00 - accuracy: 0.9877
# 5/5 [==============================] - 3s 16ms/step - loss: 0.0000e+00 - accuracy: 0.9873
# loss: 0.0000
# accuracy: 0.9873

# %%
# Model Summary
model.summary()
# Out:
# Model: "random_forest_model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
# =================================================================
# Total params: 1 (1.00 Byte)
# Trainable params: 0 (0.00 Byte)
# Non-trainable params: 1 (1.00 Byte)
# _________________________________________________________________
# Type: "RANDOM_FOREST"
# Task: CLASSIFICATION
# Label: "__LABEL"
#
# Input Features (16):
# 	GrayLevelNonUniformity
# 	GrayLevelNonUniformityNormalized
# 	GrayLevelVariance
# 	HighGrayLevelRunEmphasis
# 	LongRunEmphasis
# 	LongRunHighGrayLevelEmphasis
# 	LongRunLowGrayLevelEmphasis
# 	LowGrayLevelRunEmphasis
# 	RunEntropy
# 	RunLengthNonUniformity
# 	RunLengthNonUniformityNormalized
# 	RunPercentage
# 	RunVariance
# 	ShortRunEmphasis
# 	ShortRunHighGrayLevelEmphasis
# 	ShortRunLowGrayLevelEmphasis
#
# Trained with weights
#
# Variable Importance: INV_MEAN_MIN_DEPTH:
#     1.     "LongRunHighGrayLevelEmphasis"  0.239963 ################
#     2.         "HighGrayLevelRunEmphasis"  0.160525 #######
#     3.     "ShortRunLowGrayLevelEmphasis"  0.136204 ####
#     4.    "ShortRunHighGrayLevelEmphasis"  0.132803 ####
#     5.          "LowGrayLevelRunEmphasis"  0.126475 ###
#     6.      "LongRunLowGrayLevelEmphasis"  0.119573 ##
#     7.                       "RunEntropy"  0.116856 ##
#     8.                      "RunVariance"  0.109540 #
#     9.           "GrayLevelNonUniformity"  0.108411 #
#    10.                  "LongRunEmphasis"  0.107699 #
#    11. "GrayLevelNonUniformityNormalized"  0.102726
#    12.                "GrayLevelVariance"  0.101068
#    13.                 "ShortRunEmphasis"  0.099764
#    14. "RunLengthNonUniformityNormalized"  0.098432
#    15.                    "RunPercentage"  0.097003
#    16.           "RunLengthNonUniformity"  0.095748
#
# Variable Importance: NUM_AS_ROOT:
#     1.     "LongRunHighGrayLevelEmphasis" 98.000000 ################
#     2.         "HighGrayLevelRunEmphasis" 66.000000 ##########
#     3.     "ShortRunLowGrayLevelEmphasis" 40.000000 ######
#     4.    "ShortRunHighGrayLevelEmphasis" 37.000000 #####
#     5.          "LowGrayLevelRunEmphasis" 31.000000 ####
#     6.      "LongRunLowGrayLevelEmphasis" 10.000000 #
#     7. "GrayLevelNonUniformityNormalized"  8.000000 #
#     8.           "GrayLevelNonUniformity"  5.000000
#     9.                       "RunEntropy"  3.000000
#    10. "RunLengthNonUniformityNormalized"  1.000000
#    11.                      "RunVariance"  1.000000
#
# Variable Importance: NUM_NODES:
#     1.                       "RunEntropy" 10655.000000 ################
#     2.     "LongRunHighGrayLevelEmphasis" 10225.000000 ##############
#     3.                "GrayLevelVariance" 9441.000000 ############
#     4.           "GrayLevelNonUniformity" 9108.000000 ###########
#     5. "GrayLevelNonUniformityNormalized" 8500.000000 #########
#     6.         "HighGrayLevelRunEmphasis" 8339.000000 ########
#     7.     "ShortRunLowGrayLevelEmphasis" 8296.000000 ########
#     8.    "ShortRunHighGrayLevelEmphasis" 8140.000000 ########
#     9.      "LongRunLowGrayLevelEmphasis" 8125.000000 ########
#    10.          "LowGrayLevelRunEmphasis" 8087.000000 #######
#    11.                      "RunVariance" 7866.000000 #######
#    12.                  "LongRunEmphasis" 7063.000000 ####
#    13. "RunLengthNonUniformityNormalized" 6310.000000 ##
#    14.                 "ShortRunEmphasis" 6203.000000 #
#    15.           "RunLengthNonUniformity" 6163.000000 #
#    16.                    "RunPercentage" 5578.000000
#
# Variable Importance: SUM_SCORE:
#     1.     "LongRunHighGrayLevelEmphasis" 1342087.499869 ################
#     2.         "HighGrayLevelRunEmphasis" 819765.981461 #########
#     3.    "ShortRunHighGrayLevelEmphasis" 550683.025676 #####
#     4.     "ShortRunLowGrayLevelEmphasis" 525285.905338 #####
#     5.          "LowGrayLevelRunEmphasis" 454179.864560 ####
#     6.      "LongRunLowGrayLevelEmphasis" 285968.011002 ##
#     7.                       "RunEntropy" 277923.360251 ##
#     8.                      "RunVariance" 209218.939683 #
#     9.           "GrayLevelNonUniformity" 193362.325739
#    10.                  "LongRunEmphasis" 191159.734450
#    11.                "GrayLevelVariance" 180378.872752
#    12. "GrayLevelNonUniformityNormalized" 169939.577909
#    13.                 "ShortRunEmphasis" 135522.108376
#    14. "RunLengthNonUniformityNormalized" 131332.439691
#    15.                    "RunPercentage" 123931.886563
#    16.           "RunLengthNonUniformity" 122741.279661
#
#
#
# Winner takes all: true
# Out-of-bag evaluation: accuracy:0.860517 logloss:0.550001
# Number of trees: 300
# Total number of nodes: 256498
#
# Number of nodes by tree:
# Count: 300 Average: 854.993 StdDev: 38.2987
# Min: 721 Max: 959 Ignored: 0
# ----------------------------------------------
# [ 721, 732)  1   0.33%   0.33%
# [ 732, 744)  0   0.00%   0.33%
# [ 744, 756)  1   0.33%   0.67%
# [ 756, 768)  2   0.67%   1.33% #
# [ 768, 780)  4   1.33%   2.67% #
# [ 780, 792)  8   2.67%   5.33% ##
# [ 792, 804) 10   3.33%   8.67% ###
# [ 804, 816) 25   8.33%  17.00% #######
# [ 816, 828) 23   7.67%  24.67% ######
# [ 828, 840) 29   9.67%  34.33% ########
# [ 840, 852) 38  12.67%  47.00% ##########
# [ 852, 864) 30  10.00%  57.00% ########
# [ 864, 876) 32  10.67%  67.67% ########
# [ 876, 888) 38  12.67%  80.33% ##########
# [ 888, 900) 21   7.00%  87.33% ######
# [ 900, 912) 16   5.33%  92.67% ####
# [ 912, 924) 15   5.00%  97.67% ####
# [ 924, 936)  4   1.33%  99.00% #
# [ 936, 948)  1   0.33%  99.33%
# [ 948, 959]  2   0.67% 100.00% #
#
# Depth by leafs:
# Count: 128399 Average: 11.1721 StdDev: 2.60197
# Min: 2 Max: 15 Ignored: 0
# ----------------------------------------------
# [  2,  3)     7   0.01%   0.01%
# [  3,  4)    96   0.07%   0.08%
# [  4,  5)   681   0.53%   0.61%
# [  5,  6)  1691   1.32%   1.93% #
# [  6,  7)  3206   2.50%   4.42% ##
# [  7,  8)  6028   4.69%   9.12% ###
# [  8,  9)  9373   7.30%  16.42% #####
# [  9, 10) 13071  10.18%  26.60% #######
# [ 10, 11) 16074  12.52%  39.12% #########
# [ 11, 12) 17459  13.60%  52.72% ##########
# [ 12, 13) 17117  13.33%  66.05% ##########
# [ 13, 14) 15216  11.85%  77.90% #########
# [ 14, 15) 12748   9.93%  87.83% #######
# [ 15, 15] 15632  12.17% 100.00% #########
#
# Number of training obs by leaf:
# Count: 128399 Average: 69.1524 StdDev: 277.906
# Min: 5 Max: 5129 Ignored: 0
# ----------------------------------------------
# [    5,  261) 121694  94.78%  94.78% ##########
# [  261,  517)   2992   2.33%  97.11%
# [  517,  773)   1480   1.15%  98.26%
# [  773, 1030)    631   0.49%  98.75%
# [ 1030, 1286)    382   0.30%  99.05%
# [ 1286, 1542)    208   0.16%  99.21%
# [ 1542, 1798)    156   0.12%  99.33%
# [ 1798, 2055)    143   0.11%  99.44%
# [ 2055, 2311)    119   0.09%  99.54%
# [ 2311, 2567)    101   0.08%  99.62%
# [ 2567, 2823)     91   0.07%  99.69%
# [ 2823, 3080)     60   0.05%  99.73%
# [ 3080, 3336)     85   0.07%  99.80%
# [ 3336, 3592)     87   0.07%  99.87%
# [ 3592, 3848)     93   0.07%  99.94%
# [ 3848, 4105)     45   0.04%  99.98%
# [ 4105, 4361)     11   0.01%  99.98%
# [ 4361, 4617)     11   0.01%  99.99%
# [ 4617, 4873)      5   0.00% 100.00%
# [ 4873, 5129]      5   0.00% 100.00%
#
# Attribute in nodes:
# 	10655 : RunEntropy [NUMERICAL]
# 	10225 : LongRunHighGrayLevelEmphasis [NUMERICAL]
# 	9441 : GrayLevelVariance [NUMERICAL]
# 	9108 : GrayLevelNonUniformity [NUMERICAL]
# 	8500 : GrayLevelNonUniformityNormalized [NUMERICAL]
# 	8339 : HighGrayLevelRunEmphasis [NUMERICAL]
# 	8296 : ShortRunLowGrayLevelEmphasis [NUMERICAL]
# 	8140 : ShortRunHighGrayLevelEmphasis [NUMERICAL]
# 	8125 : LongRunLowGrayLevelEmphasis [NUMERICAL]
# 	8087 : LowGrayLevelRunEmphasis [NUMERICAL]
# 	7866 : RunVariance [NUMERICAL]
# 	7063 : LongRunEmphasis [NUMERICAL]
# 	6310 : RunLengthNonUniformityNormalized [NUMERICAL]
# 	6203 : ShortRunEmphasis [NUMERICAL]
# 	6163 : RunLengthNonUniformity [NUMERICAL]
# 	5578 : RunPercentage [NUMERICAL]
#
# Attribute in nodes with depth <= 0:
# 	98 : LongRunHighGrayLevelEmphasis [NUMERICAL]
# 	66 : HighGrayLevelRunEmphasis [NUMERICAL]
# 	40 : ShortRunLowGrayLevelEmphasis [NUMERICAL]
# 	37 : ShortRunHighGrayLevelEmphasis [NUMERICAL]
# 	31 : LowGrayLevelRunEmphasis [NUMERICAL]
# 	10 : LongRunLowGrayLevelEmphasis [NUMERICAL]
# 	8 : GrayLevelNonUniformityNormalized [NUMERICAL]
# 	5 : GrayLevelNonUniformity [NUMERICAL]
# 	3 : RunEntropy [NUMERICAL]
# 	1 : RunVariance [NUMERICAL]
# 	1 : RunLengthNonUniformityNormalized [NUMERICAL]
#
# Attribute in nodes with depth <= 1:
# 	259 : LongRunHighGrayLevelEmphasis [NUMERICAL]
# 	186 : HighGrayLevelRunEmphasis [NUMERICAL]
# 	121 : ShortRunLowGrayLevelEmphasis [NUMERICAL]
# 	114 : ShortRunHighGrayLevelEmphasis [NUMERICAL]
# 	92 : LowGrayLevelRunEmphasis [NUMERICAL]
# 	81 : LongRunLowGrayLevelEmphasis [NUMERICAL]
# 	11 : GrayLevelNonUniformity [NUMERICAL]
# 	10 : GrayLevelNonUniformityNormalized [NUMERICAL]
# 	7 : RunLengthNonUniformityNormalized [NUMERICAL]
# 	6 : RunEntropy [NUMERICAL]
# 	4 : ShortRunEmphasis [NUMERICAL]
# 	3 : LongRunEmphasis [NUMERICAL]
# 	2 : RunVariance [NUMERICAL]
# 	2 : RunLengthNonUniformity [NUMERICAL]
# 	2 : GrayLevelVariance [NUMERICAL]
#
# Attribute in nodes with depth <= 2:
# 	497 : LongRunHighGrayLevelEmphasis [NUMERICAL]
# 	311 : HighGrayLevelRunEmphasis [NUMERICAL]
# 	219 : ShortRunHighGrayLevelEmphasis [NUMERICAL]
# 	191 : ShortRunLowGrayLevelEmphasis [NUMERICAL]
# 	182 : LowGrayLevelRunEmphasis [NUMERICAL]
# 	163 : LongRunLowGrayLevelEmphasis [NUMERICAL]
# 	80 : GrayLevelNonUniformity [NUMERICAL]
# 	78 : LongRunEmphasis [NUMERICAL]
# 	72 : RunVariance [NUMERICAL]
# 	59 : RunEntropy [NUMERICAL]
# 	49 : ShortRunEmphasis [NUMERICAL]
# 	48 : GrayLevelNonUniformityNormalized [NUMERICAL]
# 	43 : RunPercentage [NUMERICAL]
# 	41 : RunLengthNonUniformityNormalized [NUMERICAL]
# 	35 : GrayLevelVariance [NUMERICAL]
# 	25 : RunLengthNonUniformity [NUMERICAL]
#
# Attribute in nodes with depth <= 3:
# 	789 : LongRunHighGrayLevelEmphasis [NUMERICAL]
# 	478 : HighGrayLevelRunEmphasis [NUMERICAL]
# 	392 : LowGrayLevelRunEmphasis [NUMERICAL]
# 	366 : ShortRunLowGrayLevelEmphasis [NUMERICAL]
# 	366 : ShortRunHighGrayLevelEmphasis [NUMERICAL]
# 	323 : LongRunLowGrayLevelEmphasis [NUMERICAL]
# 	253 : RunEntropy [NUMERICAL]
# 	216 : GrayLevelNonUniformity [NUMERICAL]
# 	196 : RunVariance [NUMERICAL]
# 	194 : LongRunEmphasis [NUMERICAL]
# 	191 : GrayLevelVariance [NUMERICAL]
# 	169 : GrayLevelNonUniformityNormalized [NUMERICAL]
# 	127 : ShortRunEmphasis [NUMERICAL]
# 	124 : RunPercentage [NUMERICAL]
# 	116 : RunLengthNonUniformityNormalized [NUMERICAL]
# 	83 : RunLengthNonUniformity [NUMERICAL]
#
# Attribute in nodes with depth <= 5:
# 	1768 : LongRunHighGrayLevelEmphasis [NUMERICAL]
# 	1245 : RunEntropy [NUMERICAL]
# 	1142 : HighGrayLevelRunEmphasis [NUMERICAL]
# 	1068 : ShortRunLowGrayLevelEmphasis [NUMERICAL]
# 	1040 : LowGrayLevelRunEmphasis [NUMERICAL]
# 	969 : GrayLevelNonUniformity [NUMERICAL]
# 	949 : ShortRunHighGrayLevelEmphasis [NUMERICAL]
# 	937 : LongRunLowGrayLevelEmphasis [NUMERICAL]
# 	900 : GrayLevelVariance [NUMERICAL]
# 	811 : GrayLevelNonUniformityNormalized [NUMERICAL]
# 	808 : RunVariance [NUMERICAL]
# 	761 : LongRunEmphasis [NUMERICAL]
# 	527 : RunLengthNonUniformityNormalized [NUMERICAL]
# 	508 : ShortRunEmphasis [NUMERICAL]
# 	495 : RunPercentage [NUMERICAL]
# 	461 : RunLengthNonUniformity [NUMERICAL]
#
# Condition type in nodes:
# 	128099 : HigherCondition
# Condition type in nodes with depth <= 0:
# 	300 : HigherCondition
# Condition type in nodes with depth <= 1:
# 	900 : HigherCondition
# Condition type in nodes with depth <= 2:
# 	2093 : HigherCondition
# Condition type in nodes with depth <= 3:
# 	4383 : HigherCondition
# Condition type in nodes with depth <= 5:
# 	14389 : HigherCondition
# Node format: NOT_SET
#
# Training OOB:
# 	trees: 1, Out-of-bag evaluation: accuracy:0.832898 logloss:6.02297
# 	trees: 11, Out-of-bag evaluation: accuracy:0.840905 logloss:2.49413
# 	trees: 21, Out-of-bag evaluation: accuracy:0.847593 logloss:1.71029
# 	trees: 31, Out-of-bag evaluation: accuracy:0.854119 logloss:1.39117
# 	trees: 41, Out-of-bag evaluation: accuracy:0.859081 logloss:1.17161
# 	trees: 51, Out-of-bag evaluation: accuracy:0.858423 logloss:1.0875
# 	trees: 61, Out-of-bag evaluation: accuracy:0.858198 logloss:0.992187
# 	trees: 71, Out-of-bag evaluation: accuracy:0.858044 logloss:0.923894
# 	trees: 81, Out-of-bag evaluation: accuracy:0.856285 logloss:0.869235
# 	trees: 91, Out-of-bag evaluation: accuracy:0.857738 logloss:0.833683
# 	trees: 101, Out-of-bag evaluation: accuracy:0.857124 logloss:0.791244
# 	trees: 111, Out-of-bag evaluation: accuracy:0.858135 logloss:0.755698
# 	trees: 121, Out-of-bag evaluation: accuracy:0.857025 logloss:0.730515
# 	trees: 131, Out-of-bag evaluation: accuracy:0.858072 logloss:0.696229
# 	trees: 141, Out-of-bag evaluation: accuracy:0.858081 logloss:0.695365
# 	trees: 151, Out-of-bag evaluation: accuracy:0.858351 logloss:0.6697
# 	trees: 161, Out-of-bag evaluation: accuracy:0.857476 logloss:0.652139
# 	trees: 171, Out-of-bag evaluation: accuracy:0.859209 logloss:0.626772
# 	trees: 181, Out-of-bag evaluation: accuracy:0.858532 logloss:0.626075
# 	trees: 191, Out-of-bag evaluation: accuracy:0.859019 logloss:0.608538
# 	trees: 201, Out-of-bag evaluation: accuracy:0.857467 logloss:0.60889
# 	trees: 211, Out-of-bag evaluation: accuracy:0.85864 logloss:0.607826
# 	trees: 221, Out-of-bag evaluation: accuracy:0.859335 logloss:0.599744
# 	trees: 231, Out-of-bag evaluation: accuracy:0.859597 logloss:0.599716
# 	trees: 241, Out-of-bag evaluation: accuracy:0.860138 logloss:0.592267
# 	trees: 251, Out-of-bag evaluation: accuracy:0.859876 logloss:0.583579
# 	trees: 261, Out-of-bag evaluation: accuracy:0.859389 logloss:0.574779
# 	trees: 271, Out-of-bag evaluation: accuracy:0.859597 logloss:0.574504
# 	trees: 281, Out-of-bag evaluation: accuracy:0.860364 logloss:0.566049
# 	trees: 291, Out-of-bag evaluation: accuracy:0.859732 logloss:0.558249
# 	trees: 300, Out-of-bag evaluation: accuracy:0.860517 logloss:0.550001

# %%
# Model features
model.make_inspector().features()
# Out:
# ["GrayLevelNonUniformity" (1; #0),
#  "GrayLevelNonUniformityNormalized" (1; #1),
#  "GrayLevelVariance" (1; #2),
#  "HighGrayLevelRunEmphasis" (1; #3),
#  "LongRunEmphasis" (1; #4),
#  "LongRunHighGrayLevelEmphasis" (1; #5),
#  "LongRunLowGrayLevelEmphasis" (1; #6),
#  "LowGrayLevelRunEmphasis" (1; #7),
#  "RunEntropy" (1; #8),
#  "RunLengthNonUniformity" (1; #9),
#  "RunLengthNonUniformityNormalized" (1; #10),
#  "RunPercentage" (1; #11),
#  "RunVariance" (1; #12),
#  "ShortRunEmphasis" (1; #13),
#  "ShortRunHighGrayLevelEmphasis" (1; #14),
#  "ShortRunLowGrayLevelEmphasis" (1; #15)]

# %%
# Feature importance
model.make_inspector().variable_importances()
# Out:
# {'INV_MEAN_MIN_DEPTH': [("LongRunHighGrayLevelEmphasis" (1; #5),
#    0.2399629007036934),
#   ("HighGrayLevelRunEmphasis" (1; #3), 0.16052508045961553),
#   ("ShortRunLowGrayLevelEmphasis" (1; #15), 0.1362044001808773),
#   ("ShortRunHighGrayLevelEmphasis" (1; #14), 0.13280253422154562),
#   ("LowGrayLevelRunEmphasis" (1; #7), 0.12647518062338134),
#   ("LongRunLowGrayLevelEmphasis" (1; #6), 0.11957332858107134),
#   ("RunEntropy" (1; #8), 0.11685621409009156),
#   ("RunVariance" (1; #12), 0.10954024017219527),
#   ("GrayLevelNonUniformity" (1; #0), 0.10841076058048423),
#   ("LongRunEmphasis" (1; #4), 0.10769949669706091),
#   ("GrayLevelNonUniformityNormalized" (1; #1), 0.10272580118093798),
#   ("GrayLevelVariance" (1; #2), 0.10106792812977818),
#   ("ShortRunEmphasis" (1; #13), 0.09976400065031577),
#   ("RunLengthNonUniformityNormalized" (1; #10), 0.09843182847082294),
#   ("RunPercentage" (1; #11), 0.09700251141459798),
#   ("RunLengthNonUniformity" (1; #9), 0.09574764270181654)],
#  'NUM_AS_ROOT': [("LongRunHighGrayLevelEmphasis" (1; #5), 98.0),
#   ("HighGrayLevelRunEmphasis" (1; #3), 66.0),
#   ("ShortRunLowGrayLevelEmphasis" (1; #15), 40.0),
#   ("ShortRunHighGrayLevelEmphasis" (1; #14), 37.0),
#   ("LowGrayLevelRunEmphasis" (1; #7), 31.0),
#   ("LongRunLowGrayLevelEmphasis" (1; #6), 10.0),
#   ("GrayLevelNonUniformityNormalized" (1; #1), 8.0),
#   ("GrayLevelNonUniformity" (1; #0), 5.0),
#   ("RunEntropy" (1; #8), 3.0),
#   ("RunLengthNonUniformityNormalized" (1; #10), 1.0),
#   ("RunVariance" (1; #12), 1.0)],
#  'SUM_SCORE': [("LongRunHighGrayLevelEmphasis" (1; #5), 1342087.4998693347),
#   ("HighGrayLevelRunEmphasis" (1; #3), 819765.981460891),
#   ("ShortRunHighGrayLevelEmphasis" (1; #14), 550683.0256761364),
#   ("ShortRunLowGrayLevelEmphasis" (1; #15), 525285.905337864),
#   ("LowGrayLevelRunEmphasis" (1; #7), 454179.8645602266),
#   ("LongRunLowGrayLevelEmphasis" (1; #6), 285968.0110018475),
#   ("RunEntropy" (1; #8), 277923.36025075614),
#   ("RunVariance" (1; #12), 209218.93968255617),
#   ("GrayLevelNonUniformity" (1; #0), 193362.32573946362),
#   ("LongRunEmphasis" (1; #4), 191159.73445044813),
#   ("GrayLevelVariance" (1; #2), 180378.87275198576),
#   ("GrayLevelNonUniformityNormalized" (1; #1), 169939.5779086958),
#   ("ShortRunEmphasis" (1; #13), 135522.1083760836),
#   ("RunLengthNonUniformityNormalized" (1; #10), 131332.43969051327),
#   ("RunPercentage" (1; #11), 123931.88656332529),
#   ("RunLengthNonUniformity" (1; #9), 122741.27966132709)],
#  'NUM_NODES': [("RunEntropy" (1; #8), 10655.0),
#   ("LongRunHighGrayLevelEmphasis" (1; #5), 10225.0),
#   ("GrayLevelVariance" (1; #2), 9441.0),
#   ("GrayLevelNonUniformity" (1; #0), 9108.0),
#   ("GrayLevelNonUniformityNormalized" (1; #1), 8500.0),
#   ("HighGrayLevelRunEmphasis" (1; #3), 8339.0),
#   ("ShortRunLowGrayLevelEmphasis" (1; #15), 8296.0),
#   ("ShortRunHighGrayLevelEmphasis" (1; #14), 8140.0),
#   ("LongRunLowGrayLevelEmphasis" (1; #6), 8125.0),
#   ("LowGrayLevelRunEmphasis" (1; #7), 8087.0),
#   ("RunVariance" (1; #12), 7866.0),
#   ("LongRunEmphasis" (1; #4), 7063.0),
#   ("RunLengthNonUniformityNormalized" (1; #10), 6310.0),
#   ("ShortRunEmphasis" (1; #13), 6203.0),
#   ("RunLengthNonUniformity" (1; #9), 6163.0),
#   ("RunPercentage" (1; #11), 5578.0)]}

# %%
# Model self evaluation
model.make_inspector().evaluation()
# Out:
# Evaluation(num_examples=29597, accuracy=0.8605168337038516, loss=0.5500006933023298, rmse=None, ndcg=None, aucs=None, auuc=None, qini=None)

# %%
logs = model.make_inspector().training_logs()

plt.figure(figsize=(12, 4))
plt.subplot(1, 2, 1)
plt.plot([log.num_trees for log in logs], [log.evaluation.accuracy for log in logs])
plt.xlabel("Number of trees")
plt.ylabel("Accuracy (out-of-bag)")
plt.subplot(1, 2, 2)
plt.plot([log.num_trees for log in logs], [log.evaluation.loss for log in logs])
plt.xlabel("Number of trees")
plt.ylabel("Logloss (out-of-bag)")
plt.show()

# %% [markdown]
# Calculate the score of our hold-out validation dataset

# %%
predictions = model.predict(val_ds)
y_true      = validation_data["label"]

from sklearn.metrics import roc_auc_score
ROC_AUC = roc_auc_score(y_true, predictions)
print("The ROC AUC score is %.5f" % ROC_AUC )
# Out:
# 1/5 [=====>........................] - ETA: 0s
# 4/5 [=======================>......] - ETA: 0s
# 5/5 [==============================] - 0s 15ms/step
# The ROC AUC score is 0.99625

# %%
# Compute binary classification metrics with sklearn
import numpy as np
from sklearn.metrics import (
    accuracy_score,
    precision_score,
    recall_score,
    f1_score,
    roc_auc_score,
    average_precision_score,
    confusion_matrix,
    classification_report,
    matthews_corrcoef,
    log_loss,
    brier_score_loss,
)

# Get predictions (probabilities or class labels)
preds = model.predict(test_ds)
# If model outputs probabilities, convert to labels by threshold 0.5
if preds.ndim == 2:
    # For TFDF classification, preds may be class probabilities with shape (N, 2)
    if preds.shape[1] == 2:
        pos_probs = preds[:, 1]
    else:
        # If single-probability column (positive class)
        pos_probs = preds[:, -1]
    y_pred = (pos_probs >= 0.5).astype(int)
else:
    # Already class labels
    y_pred = preds.astype(int)
    pos_probs = None

# Ground truth labels (must be 0/1 integers)
y_true = test_data["label"].astype(int).to_numpy()

# Core metrics
metrics = {}
metrics["accuracy"] = accuracy_score(y_true, y_pred)
metrics["precision"] = precision_score(y_true, y_pred, zero_division=0)
metrics["recall"] = recall_score(y_true, y_pred, zero_division=0)
metrics["f1"] = f1_score(y_true, y_pred, zero_division=0)
metrics["mcc"] = matthews_corrcoef(y_true, y_pred)

# Probabilistic metrics (only if we have probabilities)
if pos_probs is not None:
    metrics["roc_auc"] = roc_auc_score(y_true, pos_probs)
    metrics["pr_auc"] = average_precision_score(y_true, pos_probs)
    metrics["log_loss"] = log_loss(y_true, pos_probs, labels=[0,1])
    metrics["brier_score"] = brier_score_loss(y_true, pos_probs)

# Confusion matrix and detailed report
cm = confusion_matrix(y_true, y_pred, labels=[0,1])
report = classification_report(y_true, y_pred, digits=4)

print("Sklearn binary metrics:")
for k, v in metrics.items():
    print(f"{k}: {v:.4f}")
print("\nConfusion matrix:\n", cm)
print("\nClassification report:\n", report)
# Out:
# 1/9 [==>...........................] - ETA: 0s
# 4/9 [============>.................] - ETA: 0s
# 7/9 [======================>.......] - ETA: 0s
# 9/9 [==============================] - 0s 17ms/step
# Sklearn binary metrics:
# accuracy: 0.9655
# precision: 0.8830
# recall: 0.7520
# f1: 0.8122
# mcc: 0.7965
# roc_auc: 0.9560
# pr_auc: 0.8645
# log_loss: 0.1365
# brier_score: 0.0282
#
# Confusion matrix:
#  [[7923   88]
#  [ 219  664]]
#
# Classification report:
#                precision    recall  f1-score   support
#
#            0     0.9731    0.9890    0.9810      8011
#            1     0.8830    0.7520    0.8122       883
#
#     accuracy                         0.9655      8894
#    macro avg     0.9280    0.8705    0.8966      8894
# weighted avg     0.9642    0.9655    0.9642      8894
