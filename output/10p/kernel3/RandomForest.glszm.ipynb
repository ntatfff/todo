# %%
# Import packages and modules
import numpy  as np
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow_decision_forests as tfdf

from sklearn.model_selection import train_test_split
# Out:
# 2026-09-11 03:39:05.170823: I tensorflow/core/util/port.cc:113] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2026-09-11 03:39:05.518133: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2026-09-11 03:39:09.955072: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
# Check the version of TensorFlow Decision Forests
print("Found TensorFlow Decision Forests v" + tfdf.__version__)
# Out:
# Found TensorFlow Decision Forests v1.9.1

# %%
datasetPath = "dataset/10p/all/kernel3/"

# %%
# Parameters
datasetPath = "dataset/10p/glszm/kernel3/"

# %%
# train/validation/test = 70/10/20
train_data = pd.read_csv(f"{datasetPath}dataset.train.csv")
validation_data = pd.read_csv(f"{datasetPath}dataset.validation.csv")
test_data = pd.read_csv(f"{datasetPath}dataset.test.csv")

# %%
from sklearn.utils.class_weight import compute_class_weight

# tinh class weight tren tap train
classes = np.array([0, 1])
weights = compute_class_weight(class_weight="balanced", classes=classes, y=train_data["label"])
class_weight = {0: weights[0], 1: weights[1]}

# gan sample_weight cho tung dong
train_data["sample_weight"] = train_data["label"].map(class_weight)
validation_data["sample_weight"] = validation_data["label"].map(class_weight)
test_data["sample_weight"] = test_data["label"].map(class_weight)

# Convert the dataset into a TensorFlow dataset.
train_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    train_data, label="label", weight="sample_weight"
)         
val_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    validation_data, label="label", weight="sample_weight"
)
test_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    test_data, label="label", weight="sample_weight"
)
# Out:
# 2026-09-11 03:39:24.082786: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:984] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2026-09-11 03:39:24.084296: W tensorflow/core/common_runtime/gpu/gpu_device.cc:2251] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...

# %%
import keras

# %%
# %%time

# Train a Random Forest model.
model = tfdf.keras.RandomForestModel()

# Add evaluation metrics
model.compile(
    metrics=["accuracy"]
)
model.fit(x=train_ds)

# # Train a Gradient Boosted Trees model.
# model = tfdf.keras.GradientBoostedTreesModel(num_trees=1500)
# model.fit(train_ds)
# Out:
# Use /tmp/tmpvmjywh3a as temporary training directory
# Reading training dataset...
# Training dataset read in 0:00:02.543460. Found 29597 examples.
# Training model...
# [INFO 26-09-11 03:39:28.7097 UTC kernel.cc:1233] Loading model from path /tmp/tmpvmjywh3a/model/ with prefix 827959fd00494e2a
# Model trained in 0:00:02.273371
# Compiling model...
# [INFO 26-09-11 03:39:29.0162 UTC decision_forest.cc:734] Model loaded with 300 root(s), 253498 node(s), and 16 input feature(s).
# [INFO 26-09-11 03:39:29.0163 UTC abstract_model.cc:1362] Engine "RandomForestOptPred" built
# [INFO 26-09-11 03:39:29.0163 UTC kernel.cc:1061] Use fast generic engine
# Model compiled.
# CPU times: user 27 s, sys: 582 ms, total: 27.6 s
# Wall time: 7.83 s

# %%
# Evaluate the model
evaluate = model.evaluate(val_ds, return_dict=True)
print()

for name, value in evaluate.items():
    print(f"{name}: {value:.4f}")
# Out:
# WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 1/5 [=====>........................] - ETA: 10s - loss: 0.0000e+00 - accuracy: 0.9880
# 4/5 [=======================>......] - ETA: 0s - loss: 0.0000e+00 - accuracy: 0.9840
# 5/5 [==============================] - 3s 17ms/step - loss: 0.0000e+00 - accuracy: 0.9840
# loss: 0.0000
# accuracy: 0.9840

# %%
# Model Summary
model.summary()
# Out:
# Model: "random_forest_model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
# =================================================================
# Total params: 1 (1.00 Byte)
# Trainable params: 0 (0.00 Byte)
# Non-trainable params: 1 (1.00 Byte)
# _________________________________________________________________
# Type: "RANDOM_FOREST"
# Task: CLASSIFICATION
# Label: "__LABEL"
#
# Input Features (16):
# 	GrayLevelNonUniformity
# 	GrayLevelNonUniformityNormalized
# 	GrayLevelVariance
# 	HighGrayLevelZoneEmphasis
# 	LargeAreaEmphasis
# 	LargeAreaHighGrayLevelEmphasis
# 	LargeAreaLowGrayLevelEmphasis
# 	LowGrayLevelZoneEmphasis
# 	SizeZoneNonUniformity
# 	SizeZoneNonUniformityNormalized
# 	SmallAreaEmphasis
# 	SmallAreaHighGrayLevelEmphasis
# 	SmallAreaLowGrayLevelEmphasis
# 	ZoneEntropy
# 	ZonePercentage
# 	ZoneVariance
#
# Trained with weights
#
# Variable Importance: INV_MEAN_MIN_DEPTH:
#     1.        "HighGrayLevelZoneEmphasis"  0.212538 ################
#     2.           "GrayLevelNonUniformity"  0.170558 ##########
#     3.   "SmallAreaHighGrayLevelEmphasis"  0.152555 ########
#     4.    "SmallAreaLowGrayLevelEmphasis"  0.147835 #######
#     5.         "LowGrayLevelZoneEmphasis"  0.146654 #######
#     6.   "LargeAreaHighGrayLevelEmphasis"  0.141803 ######
#     7.    "LargeAreaLowGrayLevelEmphasis"  0.126322 ####
#     8.                      "ZoneEntropy"  0.102686 #
#     9.                   "ZonePercentage"  0.100517 #
#    10. "GrayLevelNonUniformityNormalized"  0.099983 #
#    11.                "GrayLevelVariance"  0.096519
#    12.            "SizeZoneNonUniformity"  0.095775
#    13.                "LargeAreaEmphasis"  0.094368
#    14.                     "ZoneVariance"  0.093999
#    15.  "SizeZoneNonUniformityNormalized"  0.091429
#    16.                "SmallAreaEmphasis"  0.090710
#
# Variable Importance: NUM_AS_ROOT:
#     1.        "HighGrayLevelZoneEmphasis" 87.000000 ################
#     2.   "SmallAreaHighGrayLevelEmphasis" 65.000000 ###########
#     3.    "SmallAreaLowGrayLevelEmphasis" 52.000000 #########
#     4.         "LowGrayLevelZoneEmphasis" 46.000000 ########
#     5.   "LargeAreaHighGrayLevelEmphasis" 17.000000 ##
#     6.    "LargeAreaLowGrayLevelEmphasis" 14.000000 ##
#     7.                      "ZoneEntropy"  9.000000 #
#     8.                     "ZoneVariance"  4.000000
#     9.           "GrayLevelNonUniformity"  2.000000
#    10. "GrayLevelNonUniformityNormalized"  2.000000
#    11.                "LargeAreaEmphasis"  2.000000
#
# Variable Importance: NUM_NODES:
#     1.           "GrayLevelNonUniformity" 10500.000000 ################
#     2.        "HighGrayLevelZoneEmphasis" 9374.000000 ############
#     3.    "LargeAreaLowGrayLevelEmphasis" 9236.000000 ###########
#     4.   "LargeAreaHighGrayLevelEmphasis" 9108.000000 ###########
#     5.         "LowGrayLevelZoneEmphasis" 8967.000000 ##########
#     6.   "SmallAreaHighGrayLevelEmphasis" 8672.000000 #########
#     7.    "SmallAreaLowGrayLevelEmphasis" 8579.000000 #########
#     8.                      "ZoneEntropy" 8202.000000 ########
#     9.                "GrayLevelVariance" 8144.000000 ########
#    10. "GrayLevelNonUniformityNormalized" 7966.000000 #######
#    11.                     "ZoneVariance" 6887.000000 ####
#    12.                "LargeAreaEmphasis" 6514.000000 ##
#    13.                "SmallAreaEmphasis" 6321.000000 ##
#    14.  "SizeZoneNonUniformityNormalized" 6305.000000 ##
#    15.            "SizeZoneNonUniformity" 6171.000000 #
#    16.                   "ZonePercentage" 5653.000000
#
# Variable Importance: SUM_SCORE:
#     1.        "HighGrayLevelZoneEmphasis" 1206240.810994 ################
#     2.   "SmallAreaHighGrayLevelEmphasis" 821028.697991 ##########
#     3.    "SmallAreaLowGrayLevelEmphasis" 670362.726952 ########
#     4.         "LowGrayLevelZoneEmphasis" 647736.394317 #######
#     5.           "GrayLevelNonUniformity" 470847.779745 #####
#     6.   "LargeAreaHighGrayLevelEmphasis" 379899.480988 ####
#     7.    "LargeAreaLowGrayLevelEmphasis" 338520.856344 ###
#     8.                      "ZoneEntropy" 168245.463513 #
#     9. "GrayLevelNonUniformityNormalized" 156834.037382
#    10.                "GrayLevelVariance" 139354.655060
#    11.                   "ZonePercentage" 128321.052194
#    12.                     "ZoneVariance" 120930.302388
#    13.                "LargeAreaEmphasis" 117697.867580
#    14.            "SizeZoneNonUniformity" 113644.976274
#    15.  "SizeZoneNonUniformityNormalized" 99136.337617
#    16.                "SmallAreaEmphasis" 96985.925670
#
#
#
# Winner takes all: true
# Out-of-bag evaluation: accuracy:0.859588 logloss:0.504035
# Number of trees: 300
# Total number of nodes: 253498
#
# Number of nodes by tree:
# Count: 300 Average: 844.993 StdDev: 40.2027
# Min: 751 Max: 947 Ignored: 0
# ----------------------------------------------
# [ 751, 760)  2   0.67%   0.67% #
# [ 760, 770)  5   1.67%   2.33% #
# [ 770, 780)  9   3.00%   5.33% ###
# [ 780, 790) 10   3.33%   8.67% ###
# [ 790, 800) 19   6.33%  15.00% #####
# [ 800, 810) 19   6.33%  21.33% #####
# [ 810, 819) 13   4.33%  25.67% ####
# [ 819, 829) 35  11.67%  37.33% ##########
# [ 829, 839) 20   6.67%  44.00% ######
# [ 839, 849) 27   9.00%  53.00% ########
# [ 849, 859) 24   8.00%  61.00% #######
# [ 859, 869) 34  11.33%  72.33% ##########
# [ 869, 879) 13   4.33%  76.67% ####
# [ 879, 888) 24   8.00%  84.67% #######
# [ 888, 898) 17   5.67%  90.33% #####
# [ 898, 908) 11   3.67%  94.00% ###
# [ 908, 918)  6   2.00%  96.00% ##
# [ 918, 928)  4   1.33%  97.33% #
# [ 928, 938)  6   2.00%  99.33% ##
# [ 938, 947]  2   0.67% 100.00% #
#
# Depth by leafs:
# Count: 126899 Average: 11.2126 StdDev: 2.66511
# Min: 2 Max: 15 Ignored: 0
# ----------------------------------------------
# [  2,  3)     2   0.00%   0.00%
# [  3,  4)   115   0.09%   0.09%
# [  4,  5)   565   0.45%   0.54%
# [  5,  6)  1653   1.30%   1.84% #
# [  6,  7)  3691   2.91%   4.75% ##
# [  7,  8)  6282   4.95%   9.70% ####
# [  8,  9)  9572   7.54%  17.24% ######
# [  9, 10) 12549   9.89%  27.13% #######
# [ 10, 11) 14810  11.67%  38.80% #########
# [ 11, 12) 16228  12.79%  51.59% #########
# [ 12, 13) 16302  12.85%  64.44% #########
# [ 13, 14) 14908  11.75%  76.18% #########
# [ 14, 15) 13010  10.25%  86.44% ########
# [ 15, 15] 17212  13.56% 100.00% ##########
#
# Number of training obs by leaf:
# Count: 126899 Average: 69.9698 StdDev: 278.259
# Min: 5 Max: 6146 Ignored: 0
# ----------------------------------------------
# [    5,  312) 121193  95.50%  95.50% ##########
# [  312,  619)   2676   2.11%  97.61%
# [  619,  926)   1077   0.85%  98.46%
# [  926, 1233)    528   0.42%  98.88%
# [ 1233, 1540)    337   0.27%  99.14%
# [ 1540, 1847)    252   0.20%  99.34%
# [ 1847, 2154)    177   0.14%  99.48%
# [ 2154, 2461)    157   0.12%  99.60%
# [ 2461, 2768)    141   0.11%  99.72%
# [ 2768, 3076)    114   0.09%  99.81%
# [ 3076, 3383)     79   0.06%  99.87%
# [ 3383, 3690)     62   0.05%  99.92%
# [ 3690, 3997)     39   0.03%  99.95%
# [ 3997, 4304)     31   0.02%  99.97%
# [ 4304, 4611)     15   0.01%  99.98%
# [ 4611, 4918)      9   0.01%  99.99%
# [ 4918, 5225)      6   0.00% 100.00%
# [ 5225, 5532)      3   0.00% 100.00%
# [ 5532, 5839)      2   0.00% 100.00%
# [ 5839, 6146]      1   0.00% 100.00%
#
# Attribute in nodes:
# 	10500 : GrayLevelNonUniformity [NUMERICAL]
# 	9374 : HighGrayLevelZoneEmphasis [NUMERICAL]
# 	9236 : LargeAreaLowGrayLevelEmphasis [NUMERICAL]
# 	9108 : LargeAreaHighGrayLevelEmphasis [NUMERICAL]
# 	8967 : LowGrayLevelZoneEmphasis [NUMERICAL]
# 	8672 : SmallAreaHighGrayLevelEmphasis [NUMERICAL]
# 	8579 : SmallAreaLowGrayLevelEmphasis [NUMERICAL]
# 	8202 : ZoneEntropy [NUMERICAL]
# 	8144 : GrayLevelVariance [NUMERICAL]
# 	7966 : GrayLevelNonUniformityNormalized [NUMERICAL]
# 	6887 : ZoneVariance [NUMERICAL]
# 	6514 : LargeAreaEmphasis [NUMERICAL]
# 	6321 : SmallAreaEmphasis [NUMERICAL]
# 	6305 : SizeZoneNonUniformityNormalized [NUMERICAL]
# 	6171 : SizeZoneNonUniformity [NUMERICAL]
# 	5653 : ZonePercentage [NUMERICAL]
#
# Attribute in nodes with depth <= 0:
# 	87 : HighGrayLevelZoneEmphasis [NUMERICAL]
# 	65 : SmallAreaHighGrayLevelEmphasis [NUMERICAL]
# 	52 : SmallAreaLowGrayLevelEmphasis [NUMERICAL]
# 	46 : LowGrayLevelZoneEmphasis [NUMERICAL]
# 	17 : LargeAreaHighGrayLevelEmphasis [NUMERICAL]
# 	14 : LargeAreaLowGrayLevelEmphasis [NUMERICAL]
# 	9 : ZoneEntropy [NUMERICAL]
# 	4 : ZoneVariance [NUMERICAL]
# 	2 : LargeAreaEmphasis [NUMERICAL]
# 	2 : GrayLevelNonUniformityNormalized [NUMERICAL]
# 	2 : GrayLevelNonUniformity [NUMERICAL]
#
# Attribute in nodes with depth <= 1:
# 	232 : HighGrayLevelZoneEmphasis [NUMERICAL]
# 	137 : SmallAreaHighGrayLevelEmphasis [NUMERICAL]
# 	136 : LowGrayLevelZoneEmphasis [NUMERICAL]
# 	121 : SmallAreaLowGrayLevelEmphasis [NUMERICAL]
# 	73 : LargeAreaHighGrayLevelEmphasis [NUMERICAL]
# 	73 : GrayLevelNonUniformity [NUMERICAL]
# 	43 : LargeAreaLowGrayLevelEmphasis [NUMERICAL]
# 	22 : ZonePercentage [NUMERICAL]
# 	18 : ZoneEntropy [NUMERICAL]
# 	15 : SizeZoneNonUniformity [NUMERICAL]
# 	8 : GrayLevelNonUniformityNormalized [NUMERICAL]
# 	6 : SmallAreaEmphasis [NUMERICAL]
# 	5 : ZoneVariance [NUMERICAL]
# 	5 : SizeZoneNonUniformityNormalized [NUMERICAL]
# 	5 : LargeAreaEmphasis [NUMERICAL]
# 	1 : GrayLevelVariance [NUMERICAL]
#
# Attribute in nodes with depth <= 2:
# 	442 : HighGrayLevelZoneEmphasis [NUMERICAL]
# 	285 : LowGrayLevelZoneEmphasis [NUMERICAL]
# 	273 : SmallAreaHighGrayLevelEmphasis [NUMERICAL]
# 	271 : SmallAreaLowGrayLevelEmphasis [NUMERICAL]
# 	219 : GrayLevelNonUniformity [NUMERICAL]
# 	176 : LargeAreaHighGrayLevelEmphasis [NUMERICAL]
# 	136 : LargeAreaLowGrayLevelEmphasis [NUMERICAL]
# 	59 : ZonePercentage [NUMERICAL]
# 	58 : ZoneEntropy [NUMERICAL]
# 	39 : SizeZoneNonUniformity [NUMERICAL]
# 	39 : GrayLevelNonUniformityNormalized [NUMERICAL]
# 	24 : GrayLevelVariance [NUMERICAL]
# 	21 : SizeZoneNonUniformityNormalized [NUMERICAL]
# 	21 : LargeAreaEmphasis [NUMERICAL]
# 	19 : ZoneVariance [NUMERICAL]
# 	16 : SmallAreaEmphasis [NUMERICAL]
#
# Attribute in nodes with depth <= 3:
# 	716 : HighGrayLevelZoneEmphasis [NUMERICAL]
# 	561 : LowGrayLevelZoneEmphasis [NUMERICAL]
# 	530 : GrayLevelNonUniformity [NUMERICAL]
# 	481 : SmallAreaLowGrayLevelEmphasis [NUMERICAL]
# 	447 : SmallAreaHighGrayLevelEmphasis [NUMERICAL]
# 	378 : LargeAreaHighGrayLevelEmphasis [NUMERICAL]
# 	310 : LargeAreaLowGrayLevelEmphasis [NUMERICAL]
# 	161 : ZoneEntropy [NUMERICAL]
# 	145 : GrayLevelNonUniformityNormalized [NUMERICAL]
# 	128 : GrayLevelVariance [NUMERICAL]
# 	127 : ZonePercentage [NUMERICAL]
# 	97 : ZoneVariance [NUMERICAL]
# 	92 : SizeZoneNonUniformity [NUMERICAL]
# 	89 : LargeAreaEmphasis [NUMERICAL]
# 	67 : SizeZoneNonUniformityNormalized [NUMERICAL]
# 	50 : SmallAreaEmphasis [NUMERICAL]
#
# Attribute in nodes with depth <= 5:
# 	1676 : HighGrayLevelZoneEmphasis [NUMERICAL]
# 	1654 : GrayLevelNonUniformity [NUMERICAL]
# 	1494 : LowGrayLevelZoneEmphasis [NUMERICAL]
# 	1218 : SmallAreaLowGrayLevelEmphasis [NUMERICAL]
# 	1209 : LargeAreaHighGrayLevelEmphasis [NUMERICAL]
# 	1162 : SmallAreaHighGrayLevelEmphasis [NUMERICAL]
# 	1122 : LargeAreaLowGrayLevelEmphasis [NUMERICAL]
# 	781 : ZoneEntropy [NUMERICAL]
# 	780 : GrayLevelNonUniformityNormalized [NUMERICAL]
# 	689 : GrayLevelVariance [NUMERICAL]
# 	561 : LargeAreaEmphasis [NUMERICAL]
# 	534 : ZonePercentage [NUMERICAL]
# 	525 : ZoneVariance [NUMERICAL]
# 	464 : SizeZoneNonUniformity [NUMERICAL]
# 	443 : SizeZoneNonUniformityNormalized [NUMERICAL]
# 	405 : SmallAreaEmphasis [NUMERICAL]
#
# Condition type in nodes:
# 	126599 : HigherCondition
# Condition type in nodes with depth <= 0:
# 	300 : HigherCondition
# Condition type in nodes with depth <= 1:
# 	900 : HigherCondition
# Condition type in nodes with depth <= 2:
# 	2098 : HigherCondition
# Condition type in nodes with depth <= 3:
# 	4379 : HigherCondition
# Condition type in nodes with depth <= 5:
# 	14717 : HigherCondition
# Node format: NOT_SET
#
# Training OOB:
# 	trees: 1, Out-of-bag evaluation: accuracy:0.833879 logloss:5.9876
# 	trees: 11, Out-of-bag evaluation: accuracy:0.840293 logloss:2.54837
# 	trees: 23, Out-of-bag evaluation: accuracy:0.848102 logloss:1.67351
# 	trees: 33, Out-of-bag evaluation: accuracy:0.853733 logloss:1.23601
# 	trees: 43, Out-of-bag evaluation: accuracy:0.854644 logloss:0.968555
# 	trees: 53, Out-of-bag evaluation: accuracy:0.855258 logloss:0.84209
# 	trees: 63, Out-of-bag evaluation: accuracy:0.855032 logloss:0.727095
# 	trees: 73, Out-of-bag evaluation: accuracy:0.857964 logloss:0.663874
# 	trees: 83, Out-of-bag evaluation: accuracy:0.857351 logloss:0.62955
# 	trees: 93, Out-of-bag evaluation: accuracy:0.855429 logloss:0.628619
# 	trees: 103, Out-of-bag evaluation: accuracy:0.857179 logloss:0.628613
# 	trees: 113, Out-of-bag evaluation: accuracy:0.857107 logloss:0.618695
# 	trees: 123, Out-of-bag evaluation: accuracy:0.856683 logloss:0.609315
# 	trees: 133, Out-of-bag evaluation: accuracy:0.858271 logloss:0.583729
# 	trees: 143, Out-of-bag evaluation: accuracy:0.857432 logloss:0.584352
# 	trees: 153, Out-of-bag evaluation: accuracy:0.858406 logloss:0.575869
# 	trees: 163, Out-of-bag evaluation: accuracy:0.858595 logloss:0.559018
# 	trees: 173, Out-of-bag evaluation: accuracy:0.858442 logloss:0.559809
# 	trees: 183, Out-of-bag evaluation: accuracy:0.857919 logloss:0.559267
# 	trees: 193, Out-of-bag evaluation: accuracy:0.857206 logloss:0.558839
# 	trees: 203, Out-of-bag evaluation: accuracy:0.856385 logloss:0.558425
# 	trees: 213, Out-of-bag evaluation: accuracy:0.857973 logloss:0.532824
# 	trees: 223, Out-of-bag evaluation: accuracy:0.85745 logloss:0.524167
# 	trees: 233, Out-of-bag evaluation: accuracy:0.858929 logloss:0.514584
# 	trees: 243, Out-of-bag evaluation: accuracy:0.859435 logloss:0.505619
# 	trees: 253, Out-of-bag evaluation: accuracy:0.858857 logloss:0.505828
# 	trees: 263, Out-of-bag evaluation: accuracy:0.85837 logloss:0.505121
# 	trees: 273, Out-of-bag evaluation: accuracy:0.858911 logloss:0.504285
# 	trees: 283, Out-of-bag evaluation: accuracy:0.859958 logloss:0.503679
# 	trees: 293, Out-of-bag evaluation: accuracy:0.859137 logloss:0.503611
# 	trees: 300, Out-of-bag evaluation: accuracy:0.859588 logloss:0.504035

# %%
# Model features
model.make_inspector().features()
# Out:
# ["GrayLevelNonUniformity" (1; #0),
#  "GrayLevelNonUniformityNormalized" (1; #1),
#  "GrayLevelVariance" (1; #2),
#  "HighGrayLevelZoneEmphasis" (1; #3),
#  "LargeAreaEmphasis" (1; #4),
#  "LargeAreaHighGrayLevelEmphasis" (1; #5),
#  "LargeAreaLowGrayLevelEmphasis" (1; #6),
#  "LowGrayLevelZoneEmphasis" (1; #7),
#  "SizeZoneNonUniformity" (1; #8),
#  "SizeZoneNonUniformityNormalized" (1; #9),
#  "SmallAreaEmphasis" (1; #10),
#  "SmallAreaHighGrayLevelEmphasis" (1; #11),
#  "SmallAreaLowGrayLevelEmphasis" (1; #12),
#  "ZoneEntropy" (1; #13),
#  "ZonePercentage" (1; #14),
#  "ZoneVariance" (1; #15)]

# %%
# Feature importance
model.make_inspector().variable_importances()
# Out:
# {'INV_MEAN_MIN_DEPTH': [("HighGrayLevelZoneEmphasis" (1; #3),
#    0.21253827548961352),
#   ("GrayLevelNonUniformity" (1; #0), 0.17055786851833396),
#   ("SmallAreaHighGrayLevelEmphasis" (1; #11), 0.15255514593615055),
#   ("SmallAreaLowGrayLevelEmphasis" (1; #12), 0.1478347267625114),
#   ("LowGrayLevelZoneEmphasis" (1; #7), 0.14665448422395533),
#   ("LargeAreaHighGrayLevelEmphasis" (1; #5), 0.14180306885597194),
#   ("LargeAreaLowGrayLevelEmphasis" (1; #6), 0.12632240758116403),
#   ("ZoneEntropy" (1; #13), 0.10268560799722216),
#   ("ZonePercentage" (1; #14), 0.1005172903217368),
#   ("GrayLevelNonUniformityNormalized" (1; #1), 0.09998259518706498),
#   ("GrayLevelVariance" (1; #2), 0.09651886404492417),
#   ("SizeZoneNonUniformity" (1; #8), 0.09577475949219089),
#   ("LargeAreaEmphasis" (1; #4), 0.09436840671342671),
#   ("ZoneVariance" (1; #15), 0.09399929266869218),
#   ("SizeZoneNonUniformityNormalized" (1; #9), 0.09142896071968272),
#   ("SmallAreaEmphasis" (1; #10), 0.09070999778191949)],
#  'SUM_SCORE': [("HighGrayLevelZoneEmphasis" (1; #3), 1206240.8109940097),
#   ("SmallAreaHighGrayLevelEmphasis" (1; #11), 821028.69799125),
#   ("SmallAreaLowGrayLevelEmphasis" (1; #12), 670362.7269523308),
#   ("LowGrayLevelZoneEmphasis" (1; #7), 647736.3943171654),
#   ("GrayLevelNonUniformity" (1; #0), 470847.77974489296),
#   ("LargeAreaHighGrayLevelEmphasis" (1; #5), 379899.4809881681),
#   ("LargeAreaLowGrayLevelEmphasis" (1; #6), 338520.8563444198),
#   ("ZoneEntropy" (1; #13), 168245.46351266807),
#   ("GrayLevelNonUniformityNormalized" (1; #1), 156834.03738205458),
#   ("GrayLevelVariance" (1; #2), 139354.65505956364),
#   ("ZonePercentage" (1; #14), 128321.05219404862),
#   ("ZoneVariance" (1; #15), 120930.30238844326),
#   ("LargeAreaEmphasis" (1; #4), 117697.86757982321),
#   ("SizeZoneNonUniformity" (1; #8), 113644.97627447612),
#   ("SizeZoneNonUniformityNormalized" (1; #9), 99136.33761737397),
#   ("SmallAreaEmphasis" (1; #10), 96985.9256702718)],
#  'NUM_AS_ROOT': [("HighGrayLevelZoneEmphasis" (1; #3), 87.0),
#   ("SmallAreaHighGrayLevelEmphasis" (1; #11), 65.0),
#   ("SmallAreaLowGrayLevelEmphasis" (1; #12), 52.0),
#   ("LowGrayLevelZoneEmphasis" (1; #7), 46.0),
#   ("LargeAreaHighGrayLevelEmphasis" (1; #5), 17.0),
#   ("LargeAreaLowGrayLevelEmphasis" (1; #6), 14.0),
#   ("ZoneEntropy" (1; #13), 9.0),
#   ("ZoneVariance" (1; #15), 4.0),
#   ("GrayLevelNonUniformity" (1; #0), 2.0),
#   ("GrayLevelNonUniformityNormalized" (1; #1), 2.0),
#   ("LargeAreaEmphasis" (1; #4), 2.0)],
#  'NUM_NODES': [("GrayLevelNonUniformity" (1; #0), 10500.0),
#   ("HighGrayLevelZoneEmphasis" (1; #3), 9374.0),
#   ("LargeAreaLowGrayLevelEmphasis" (1; #6), 9236.0),
#   ("LargeAreaHighGrayLevelEmphasis" (1; #5), 9108.0),
#   ("LowGrayLevelZoneEmphasis" (1; #7), 8967.0),
#   ("SmallAreaHighGrayLevelEmphasis" (1; #11), 8672.0),
#   ("SmallAreaLowGrayLevelEmphasis" (1; #12), 8579.0),
#   ("ZoneEntropy" (1; #13), 8202.0),
#   ("GrayLevelVariance" (1; #2), 8144.0),
#   ("GrayLevelNonUniformityNormalized" (1; #1), 7966.0),
#   ("ZoneVariance" (1; #15), 6887.0),
#   ("LargeAreaEmphasis" (1; #4), 6514.0),
#   ("SmallAreaEmphasis" (1; #10), 6321.0),
#   ("SizeZoneNonUniformityNormalized" (1; #9), 6305.0),
#   ("SizeZoneNonUniformity" (1; #8), 6171.0),
#   ("ZonePercentage" (1; #14), 5653.0)]}

# %%
# Model self evaluation
model.make_inspector().evaluation()
# Out:
# Evaluation(num_examples=29597, accuracy=0.8595878712080874, loss=0.5040347510128461, rmse=None, ndcg=None, aucs=None, auuc=None, qini=None)

# %%
logs = model.make_inspector().training_logs()

plt.figure(figsize=(12, 4))
plt.subplot(1, 2, 1)
plt.plot([log.num_trees for log in logs], [log.evaluation.accuracy for log in logs])
plt.xlabel("Number of trees")
plt.ylabel("Accuracy (out-of-bag)")
plt.subplot(1, 2, 2)
plt.plot([log.num_trees for log in logs], [log.evaluation.loss for log in logs])
plt.xlabel("Number of trees")
plt.ylabel("Logloss (out-of-bag)")
plt.show()

# %% [markdown]
# Calculate the score of our hold-out validation dataset

# %%
predictions = model.predict(val_ds)
y_true      = validation_data["label"]

from sklearn.metrics import roc_auc_score
ROC_AUC = roc_auc_score(y_true, predictions)
print("The ROC AUC score is %.5f" % ROC_AUC )
# Out:
# 1/5 [=====>........................] - ETA: 0s
# 4/5 [=======================>......] - ETA: 0s
# 5/5 [==============================] - 0s 16ms/step
# The ROC AUC score is 0.99667

# %%
# Compute binary classification metrics with sklearn
import numpy as np
from sklearn.metrics import (
    accuracy_score,
    precision_score,
    recall_score,
    f1_score,
    roc_auc_score,
    average_precision_score,
    confusion_matrix,
    classification_report,
    matthews_corrcoef,
    log_loss,
    brier_score_loss,
)

# Get predictions (probabilities or class labels)
preds = model.predict(test_ds)
# If model outputs probabilities, convert to labels by threshold 0.5
if preds.ndim == 2:
    # For TFDF classification, preds may be class probabilities with shape (N, 2)
    if preds.shape[1] == 2:
        pos_probs = preds[:, 1]
    else:
        # If single-probability column (positive class)
        pos_probs = preds[:, -1]
    y_pred = (pos_probs >= 0.5).astype(int)
else:
    # Already class labels
    y_pred = preds.astype(int)
    pos_probs = None

# Ground truth labels (must be 0/1 integers)
y_true = test_data["label"].astype(int).to_numpy()

# Core metrics
metrics = {}
metrics["accuracy"] = accuracy_score(y_true, y_pred)
metrics["precision"] = precision_score(y_true, y_pred, zero_division=0)
metrics["recall"] = recall_score(y_true, y_pred, zero_division=0)
metrics["f1"] = f1_score(y_true, y_pred, zero_division=0)
metrics["mcc"] = matthews_corrcoef(y_true, y_pred)

# Probabilistic metrics (only if we have probabilities)
if pos_probs is not None:
    metrics["roc_auc"] = roc_auc_score(y_true, pos_probs)
    metrics["pr_auc"] = average_precision_score(y_true, pos_probs)
    metrics["log_loss"] = log_loss(y_true, pos_probs, labels=[0,1])
    metrics["brier_score"] = brier_score_loss(y_true, pos_probs)

# Confusion matrix and detailed report
cm = confusion_matrix(y_true, y_pred, labels=[0,1])
report = classification_report(y_true, y_pred, digits=4)

print("Sklearn binary metrics:")
for k, v in metrics.items():
    print(f"{k}: {v:.4f}")
print("\nConfusion matrix:\n", cm)
print("\nClassification report:\n", report)
# Out:
# 1/9 [==>...........................] - ETA: 0s
# 4/9 [============>.................] - ETA: 0s
# 7/9 [======================>.......] - ETA: 0s
# 9/9 [==============================] - 0s 19ms/step
# Sklearn binary metrics:
# accuracy: 0.9610
# precision: 0.8671
# recall: 0.7169
# f1: 0.7849
# mcc: 0.7678
# roc_auc: 0.9591
# pr_auc: 0.8588
# log_loss: 0.1298
# brier_score: 0.0302
#
# Confusion matrix:
#  [[7914   97]
#  [ 250  633]]
#
# Classification report:
#                precision    recall  f1-score   support
#
#            0     0.9694    0.9879    0.9785      8011
#            1     0.8671    0.7169    0.7849       883
#
#     accuracy                         0.9610      8894
#    macro avg     0.9183    0.8524    0.8817      8894
# weighted avg     0.9592    0.9610    0.9593      8894
