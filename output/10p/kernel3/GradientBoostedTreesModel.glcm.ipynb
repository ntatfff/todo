# %%
# Import packages and modules
import numpy  as np
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow_decision_forests as tfdf

from sklearn.model_selection import train_test_split
# Out:
# 2026-09-10 09:45:31.187415: I tensorflow/core/util/port.cc:113] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2026-09-10 09:45:31.528087: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2026-09-10 09:45:36.150980: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
# Check the version of TensorFlow Decision Forests
print("Found TensorFlow Decision Forests v" + tfdf.__version__)
# Out:
# Found TensorFlow Decision Forests v1.9.1

# %%
datasetPath = "dataset/10p/all/kernel3/"

# %%
# Parameters
datasetPath = "dataset/10p/glcm/kernel3/"

# %%
# train/validation/test = 70/10/20
train_data = pd.read_csv(f"{datasetPath}dataset.train.csv")
validation_data = pd.read_csv(f"{datasetPath}dataset.validation.csv")
test_data = pd.read_csv(f"{datasetPath}dataset.test.csv")

# %%
from sklearn.utils.class_weight import compute_class_weight

# tinh class weight tren tap train
classes = np.array([0, 1])
weights = compute_class_weight(class_weight="balanced", classes=classes, y=train_data["label"])
class_weight = {0: weights[0], 1: weights[1]}

# gan sample_weight cho tung dong
train_data["sample_weight"] = train_data["label"].map(class_weight)
validation_data["sample_weight"] = validation_data["label"].map(class_weight)
test_data["sample_weight"] = test_data["label"].map(class_weight)

# Convert the dataset into a TensorFlow dataset.
train_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    train_data, label="label", weight="sample_weight"
)         
val_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    validation_data, label="label", weight="sample_weight"
)
test_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    test_data, label="label", weight="sample_weight"
)
# Out:
# 2026-09-10 09:45:48.904869: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:984] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2026-09-10 09:45:48.906280: W tensorflow/core/common_runtime/gpu/gpu_device.cc:2251] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...

# %%
import keras

# %%
# %%time

# Train a Gradient Boosted Trees model.
model = tfdf.keras.GradientBoostedTreesModel()

# Add evaluation metrics
model.compile(
    metrics=["accuracy"]
)
model.fit(x=train_ds)

# # Train a Gradient Boosted Trees model.
# model = tfdf.keras.GradientBoostedTreesModel(num_trees=1500)
# model.fit(train_ds)
# Out:
# Use /tmp/tmpn0m8jixi as temporary training directory
# Reading training dataset...
# [WARNING 26-09-10 09:45:49.0568 UTC gradient_boosted_trees.cc:1840] "goss_alpha" set but "sampling_method" not equal to "GOSS".
# [WARNING 26-09-10 09:45:49.0571 UTC gradient_boosted_trees.cc:1851] "goss_beta" set but "sampling_method" not equal to "GOSS".
# [WARNING 26-09-10 09:45:49.0571 UTC gradient_boosted_trees.cc:1865] "selective_gradient_boosting_ratio" set but "sampling_method" not equal to "SELGB".
# Training dataset read in 0:00:03.467448. Found 29597 examples.
# Training model...
# Model trained in 0:00:05.482945
# Compiling model...
# [INFO 26-09-10 09:45:58.0287 UTC kernel.cc:1233] Loading model from path /tmp/tmpn0m8jixi/model/ with prefix 7539f4cd6c2040ea
# [INFO 26-09-10 09:45:58.0366 UTC quick_scorer_extended.cc:911] The binary was compiled without AVX2 support, but your CPU supports it. Enable it for faster model inference.
# [INFO 26-09-10 09:45:58.0371 UTC abstract_model.cc:1362] Engine "GradientBoostedTreesQuickScorerExtended" built
# [INFO 26-09-10 09:45:58.0371 UTC kernel.cc:1061] Use fast generic engine
# Model compiled.
# CPU times: user 44.9 s, sys: 1.77 s, total: 46.7 s
# Wall time: 12.2 s

# %%
# Evaluate the model
evaluate = model.evaluate(val_ds, return_dict=True)
print()

for name, value in evaluate.items():
    print(f"{name}: {value:.4f}")
# Out:
# WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 1/5 [=====>........................] - ETA: 12s - loss: 0.0000e+00 - accuracy: 0.9960
# 5/5 [==============================] - 3s 6ms/step - loss: 0.0000e+00 - accuracy: 0.9926
# loss: 0.0000
# accuracy: 0.9926

# %%
# Model Summary
model.summary()
# Out:
# Model: "gradient_boosted_trees_model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
# =================================================================
# Total params: 1 (1.00 Byte)
# Trainable params: 0 (0.00 Byte)
# Non-trainable params: 1 (1.00 Byte)
# _________________________________________________________________
# Type: "GRADIENT_BOOSTED_TREES"
# Task: CLASSIFICATION
# Label: "__LABEL"
#
# Input Features (24):
# 	Autocorrelation
# 	ClusterProminence
# 	ClusterShade
# 	ClusterTendency
# 	Contrast
# 	Correlation
# 	DifferenceAverage
# 	DifferenceEntropy
# 	DifferenceVariance
# 	Id
# 	Idm
# 	Idmn
# 	Idn
# 	Imc1
# 	Imc2
# 	InverseVariance
# 	JointAverage
# 	JointEnergy
# 	JointEntropy
# 	MCC
# 	MaximumProbability
# 	SumAverage
# 	SumEntropy
# 	SumSquares
#
# Trained with weights
#
# Variable Importance: INV_MEAN_MIN_DEPTH:
#     1.    "Autocorrelation"  0.255124 ################
#     2.       "JointAverage"  0.250331 ###############
#     3.         "SumAverage"  0.214905 ########
#     4.        "Correlation"  0.214555 ########
#     5.                "Idn"  0.213668 #######
#     6.               "Idmn"  0.201633 #####
#     7.       "ClusterShade"  0.193380 ####
#     8.    "InverseVariance"  0.190992 ###
#     9. "DifferenceVariance"  0.186730 ##
#    10.  "DifferenceAverage"  0.182605 #
#    11.                "Idm"  0.181115 #
#    12.  "DifferenceEntropy"  0.179335 #
#    13. "MaximumProbability"  0.179286 #
#    14.                "MCC"  0.179199 #
#    15.                 "Id"  0.178612 #
#    16.           "Contrast"  0.178439 #
#    17.         "SumEntropy"  0.177730
#    18.        "JointEnergy"  0.177453
#    19.               "Imc1"  0.174335
#    20.       "JointEntropy"  0.173563
#    21.         "SumSquares"  0.173285
#    22.    "ClusterTendency"  0.173225
#    23.               "Imc2"  0.172961
#    24.  "ClusterProminence"  0.172687
#
# Variable Importance: NUM_AS_ROOT:
#     1.       "JointAverage" 47.000000 ################
#     2.    "Autocorrelation" 31.000000 ##########
#     3.         "SumAverage" 23.000000 #######
#     4.        "Correlation" 20.000000 ######
#     5.               "Idmn"  9.000000 ##
#     6.                "Idn"  6.000000 #
#     7.        "JointEnergy"  4.000000 #
#     8. "DifferenceVariance"  3.000000
#     9.         "SumEntropy"  3.000000
#    10.                "MCC"  2.000000
#    11.           "Contrast"  1.000000
#    12.       "JointEntropy"  1.000000
#
# Variable Importance: NUM_NODES:
#     1.    "Autocorrelation" 515.000000 ################
#     2.                "Idn" 436.000000 #############
#     3.               "Idmn" 283.000000 ########
#     4.       "ClusterShade" 273.000000 ########
#     5.       "JointAverage" 247.000000 #######
#     6.        "Correlation" 243.000000 #######
#     7.         "SumAverage" 236.000000 ######
#     8.    "InverseVariance" 163.000000 ####
#     9.  "DifferenceAverage" 157.000000 ####
#    10. "DifferenceVariance" 138.000000 ###
#    11. "MaximumProbability" 125.000000 ###
#    12.  "DifferenceEntropy" 118.000000 ###
#    13.                "MCC" 114.000000 ##
#    14.                "Idm" 104.000000 ##
#    15.           "Contrast" 102.000000 ##
#    16.                 "Id" 92.000000 ##
#    17.         "SumEntropy" 84.000000 #
#    18.               "Imc1" 79.000000 #
#    19.        "JointEnergy" 65.000000 #
#    20.    "ClusterTendency" 45.000000
#    21.               "Imc2" 45.000000
#    22.         "SumSquares" 39.000000
#    23.  "ClusterProminence" 38.000000
#    24.       "JointEntropy" 26.000000
#
# Variable Importance: SUM_SCORE:
#     1.    "Autocorrelation" 18026.342632 ################
#     2.                "Idn" 3063.864222 ##
#     3.    "InverseVariance" 2041.045957 #
#     4.       "JointAverage" 1970.362594 #
#     5.         "SumAverage" 1653.268531 #
#     6.        "Correlation" 1003.720096
#     7.               "Idmn" 803.439571
#     8.  "DifferenceEntropy" 714.250919
#     9.  "DifferenceAverage" 697.357093
#    10.       "ClusterShade" 686.651951
#    11.               "Imc1" 531.956189
#    12.                "Idm" 413.810788
#    13.                 "Id" 352.523369
#    14. "DifferenceVariance" 249.937531
#    15. "MaximumProbability" 229.931717
#    16.         "SumEntropy" 228.867529
#    17.           "Contrast" 196.575999
#    18.                "MCC" 140.401437
#    19.         "SumSquares" 113.914793
#    20.        "JointEnergy" 111.050084
#    21.    "ClusterTendency" 83.808835
#    22.               "Imc2" 74.667857
#    23.  "ClusterProminence" 33.960883
#    24.       "JointEntropy" 20.702333
#
#
#
# Loss: BINOMIAL_LOG_LIKELIHOOD
# Validation loss value: 0.290637
# Number of trees per iteration: 1
# Node format: NOT_SET
# Number of trees: 150
# Total number of nodes: 7684
#
# Number of nodes by tree:
# Count: 150 Average: 51.2267 StdDev: 8.79556
# Min: 21 Max: 63 Ignored: 0
# ----------------------------------------------
# [ 21, 23)  1   0.67%   0.67%
# [ 23, 25)  0   0.00%   0.67%
# [ 25, 27)  0   0.00%   0.67%
# [ 27, 29)  1   0.67%   1.33%
# [ 29, 31)  0   0.00%   1.33%
# [ 31, 33)  1   0.67%   2.00%
# [ 33, 36)  5   3.33%   5.33% ##
# [ 36, 38)  1   0.67%   6.00%
# [ 38, 40)  5   3.33%   9.33% ##
# [ 40, 42)  8   5.33%  14.67% ###
# [ 42, 44)  7   4.67%  19.33% ##
# [ 44, 46) 16  10.67%  30.00% #####
# [ 46, 48) 11   7.33%  37.33% ####
# [ 48, 51) 14   9.33%  46.67% #####
# [ 51, 53)  4   2.67%  49.33% #
# [ 53, 55) 14   9.33%  58.67% #####
# [ 55, 57)  6   4.00%  62.67% ##
# [ 57, 59) 13   8.67%  71.33% ####
# [ 59, 61) 12   8.00%  79.33% ####
# [ 61, 63] 31  20.67% 100.00% ##########
#
# Depth by leafs:
# Count: 3917 Average: 4.85091 StdDev: 0.497358
# Min: 1 Max: 5 Ignored: 0
# ----------------------------------------------
# [ 1, 2)    5   0.13%   0.13%
# [ 2, 3)   38   0.97%   1.10%
# [ 3, 4)   92   2.35%   3.45%
# [ 4, 5)  266   6.79%  10.24% #
# [ 5, 5] 3516  89.76% 100.00% ##########
#
# Number of training obs by leaf:
# Count: 3917 Average: 1020.9 StdDev: 2516.03
# Min: 5 Max: 23261 Ignored: 0
# ----------------------------------------------
# [     5,  1167) 3117  79.58%  79.58% ##########
# [  1167,  2330)  323   8.25%  87.82% #
# [  2330,  3493)  160   4.08%  91.91% #
# [  3493,  4656)  110   2.81%  94.72%
# [  4656,  5819)   48   1.23%  95.94%
# [  5819,  6982)   29   0.74%  96.68%
# [  6982,  8144)   33   0.84%  97.52%
# [  8144,  9307)   20   0.51%  98.03%
# [  9307, 10470)   11   0.28%  98.32%
# [ 10470, 11633)    8   0.20%  98.52%
# [ 11633, 12796)   15   0.38%  98.90%
# [ 12796, 13959)    6   0.15%  99.06%
# [ 13959, 15122)    5   0.13%  99.18%
# [ 15122, 16284)    2   0.05%  99.23%
# [ 16284, 17447)    5   0.13%  99.36%
# [ 17447, 18610)    4   0.10%  99.46%
# [ 18610, 19773)    8   0.20%  99.67%
# [ 19773, 20936)    4   0.10%  99.77%
# [ 20936, 22099)    2   0.05%  99.82%
# [ 22099, 23261]    7   0.18% 100.00%
#
# Attribute in nodes:
# 	515 : Autocorrelation [NUMERICAL]
# 	436 : Idn [NUMERICAL]
# 	283 : Idmn [NUMERICAL]
# 	273 : ClusterShade [NUMERICAL]
# 	247 : JointAverage [NUMERICAL]
# 	243 : Correlation [NUMERICAL]
# 	236 : SumAverage [NUMERICAL]
# 	163 : InverseVariance [NUMERICAL]
# 	157 : DifferenceAverage [NUMERICAL]
# 	138 : DifferenceVariance [NUMERICAL]
# 	125 : MaximumProbability [NUMERICAL]
# 	118 : DifferenceEntropy [NUMERICAL]
# 	114 : MCC [NUMERICAL]
# 	104 : Idm [NUMERICAL]
# 	102 : Contrast [NUMERICAL]
# 	92 : Id [NUMERICAL]
# 	84 : SumEntropy [NUMERICAL]
# 	79 : Imc1 [NUMERICAL]
# 	65 : JointEnergy [NUMERICAL]
# 	45 : Imc2 [NUMERICAL]
# 	45 : ClusterTendency [NUMERICAL]
# 	39 : SumSquares [NUMERICAL]
# 	38 : ClusterProminence [NUMERICAL]
# 	26 : JointEntropy [NUMERICAL]
#
# Attribute in nodes with depth <= 0:
# 	47 : JointAverage [NUMERICAL]
# 	31 : Autocorrelation [NUMERICAL]
# 	23 : SumAverage [NUMERICAL]
# 	20 : Correlation [NUMERICAL]
# 	9 : Idmn [NUMERICAL]
# 	6 : Idn [NUMERICAL]
# 	4 : JointEnergy [NUMERICAL]
# 	3 : SumEntropy [NUMERICAL]
# 	3 : DifferenceVariance [NUMERICAL]
# 	2 : MCC [NUMERICAL]
# 	1 : JointEntropy [NUMERICAL]
# 	1 : Contrast [NUMERICAL]
#
# Attribute in nodes with depth <= 1:
# 	85 : Autocorrelation [NUMERICAL]
# 	76 : JointAverage [NUMERICAL]
# 	54 : Correlation [NUMERICAL]
# 	42 : SumAverage [NUMERICAL]
# 	30 : Idn [NUMERICAL]
# 	29 : InverseVariance [NUMERICAL]
# 	25 : ClusterShade [NUMERICAL]
# 	23 : Idmn [NUMERICAL]
# 	18 : DifferenceVariance [NUMERICAL]
# 	11 : DifferenceAverage [NUMERICAL]
# 	9 : MCC [NUMERICAL]
# 	9 : Idm [NUMERICAL]
# 	8 : SumEntropy [NUMERICAL]
# 	7 : Id [NUMERICAL]
# 	5 : Contrast [NUMERICAL]
# 	4 : MaximumProbability [NUMERICAL]
# 	4 : JointEnergy [NUMERICAL]
# 	4 : DifferenceEntropy [NUMERICAL]
# 	1 : SumSquares [NUMERICAL]
# 	1 : JointEntropy [NUMERICAL]
#
# Attribute in nodes with depth <= 2:
# 	176 : Autocorrelation [NUMERICAL]
# 	102 : JointAverage [NUMERICAL]
# 	95 : Idn [NUMERICAL]
# 	87 : SumAverage [NUMERICAL]
# 	84 : Correlation [NUMERICAL]
# 	73 : ClusterShade [NUMERICAL]
# 	66 : Idmn [NUMERICAL]
# 	48 : InverseVariance [NUMERICAL]
# 	41 : DifferenceVariance [NUMERICAL]
# 	32 : MaximumProbability [NUMERICAL]
# 	32 : Idm [NUMERICAL]
# 	27 : DifferenceEntropy [NUMERICAL]
# 	25 : DifferenceAverage [NUMERICAL]
# 	20 : MCC [NUMERICAL]
# 	18 : SumEntropy [NUMERICAL]
# 	18 : Id [NUMERICAL]
# 	18 : Contrast [NUMERICAL]
# 	9 : JointEnergy [NUMERICAL]
# 	7 : JointEntropy [NUMERICAL]
# 	5 : SumSquares [NUMERICAL]
# 	5 : Imc1 [NUMERICAL]
# 	5 : ClusterTendency [NUMERICAL]
# 	3 : Imc2 [NUMERICAL]
# 	1 : ClusterProminence [NUMERICAL]
#
# Attribute in nodes with depth <= 3:
# 	305 : Autocorrelation [NUMERICAL]
# 	248 : Idn [NUMERICAL]
# 	153 : JointAverage [NUMERICAL]
# 	153 : Idmn [NUMERICAL]
# 	143 : ClusterShade [NUMERICAL]
# 	139 : Correlation [NUMERICAL]
# 	132 : SumAverage [NUMERICAL]
# 	90 : InverseVariance [NUMERICAL]
# 	75 : DifferenceVariance [NUMERICAL]
# 	73 : DifferenceAverage [NUMERICAL]
# 	67 : MaximumProbability [NUMERICAL]
# 	64 : Idm [NUMERICAL]
# 	59 : DifferenceEntropy [NUMERICAL]
# 	54 : MCC [NUMERICAL]
# 	46 : Contrast [NUMERICAL]
# 	39 : Id [NUMERICAL]
# 	33 : SumEntropy [NUMERICAL]
# 	33 : Imc1 [NUMERICAL]
# 	32 : JointEnergy [NUMERICAL]
# 	17 : ClusterTendency [NUMERICAL]
# 	15 : SumSquares [NUMERICAL]
# 	15 : Imc2 [NUMERICAL]
# 	13 : ClusterProminence [NUMERICAL]
# 	11 : JointEntropy [NUMERICAL]
#
# Attribute in nodes with depth <= 5:
# 	515 : Autocorrelation [NUMERICAL]
# 	436 : Idn [NUMERICAL]
# 	283 : Idmn [NUMERICAL]
# 	273 : ClusterShade [NUMERICAL]
# 	247 : JointAverage [NUMERICAL]
# 	243 : Correlation [NUMERICAL]
# 	236 : SumAverage [NUMERICAL]
# 	163 : InverseVariance [NUMERICAL]
# 	157 : DifferenceAverage [NUMERICAL]
# 	138 : DifferenceVariance [NUMERICAL]
# 	125 : MaximumProbability [NUMERICAL]
# 	118 : DifferenceEntropy [NUMERICAL]
# 	114 : MCC [NUMERICAL]
# 	104 : Idm [NUMERICAL]
# 	102 : Contrast [NUMERICAL]
# 	92 : Id [NUMERICAL]
# 	84 : SumEntropy [NUMERICAL]
# 	79 : Imc1 [NUMERICAL]
# 	65 : JointEnergy [NUMERICAL]
# 	45 : Imc2 [NUMERICAL]
# 	45 : ClusterTendency [NUMERICAL]
# 	39 : SumSquares [NUMERICAL]
# 	38 : ClusterProminence [NUMERICAL]
# 	26 : JointEntropy [NUMERICAL]
#
# Condition type in nodes:
# 	3767 : HigherCondition
# Condition type in nodes with depth <= 0:
# 	150 : HigherCondition
# Condition type in nodes with depth <= 1:
# 	445 : HigherCondition
# Condition type in nodes with depth <= 2:
# 	997 : HigherCondition
# Condition type in nodes with depth <= 3:
# 	2009 : HigherCondition
# Condition type in nodes with depth <= 5:
# 	3767 : HigherCondition
#
# Training logs:
# Number of iteration to final model: 150
# 	Iter:1 train-loss:1.249527 valid-loss:1.263605  train-accuracy:0.910341 valid-accuracy:0.874249
# 	Iter:2 train-loss:1.135152 valid-loss:1.159648  train-accuracy:0.918174 valid-accuracy:0.878338
# 	Iter:3 train-loss:1.040030 valid-loss:1.074875  train-accuracy:0.917090 valid-accuracy:0.881115
# 	Iter:4 train-loss:0.957727 valid-loss:0.997375  train-accuracy:0.918560 valid-accuracy:0.883431
# 	Iter:5 train-loss:0.887486 valid-loss:0.934364  train-accuracy:0.922241 valid-accuracy:0.888713
# 	Iter:6 train-loss:0.824560 valid-loss:0.878201  train-accuracy:0.925079 valid-accuracy:0.884729
# 	Iter:16 train-loss:0.487357 valid-loss:0.580170  train-accuracy:0.937546 valid-accuracy:0.897424
# 	Iter:26 train-loss:0.357443 valid-loss:0.472141  train-accuracy:0.948967 valid-accuracy:0.915958
# 	Iter:36 train-loss:0.286417 valid-loss:0.411827  train-accuracy:0.960604 valid-accuracy:0.928839
# 	Iter:46 train-loss:0.234553 valid-loss:0.375617  train-accuracy:0.970262 valid-accuracy:0.939124
# 	Iter:56 train-loss:0.195788 valid-loss:0.345858  train-accuracy:0.977200 valid-accuracy:0.940607
# 	Iter:66 train-loss:0.169466 valid-loss:0.328841  train-accuracy:0.982999 valid-accuracy:0.945148
# 	Iter:76 train-loss:0.151492 valid-loss:0.321890  train-accuracy:0.985948 valid-accuracy:0.946446
# 	Iter:86 train-loss:0.137280 valid-loss:0.309755  train-accuracy:0.988658 valid-accuracy:0.947930
# 	Iter:96 train-loss:0.123659 valid-loss:0.303164  train-accuracy:0.990658 valid-accuracy:0.949228
# 	Iter:106 train-loss:0.112906 valid-loss:0.301123  train-accuracy:0.992577 valid-accuracy:0.949413
# 	Iter:116 train-loss:0.103777 valid-loss:0.298313  train-accuracy:0.993107 valid-accuracy:0.947097
# 	Iter:126 train-loss:0.095716 valid-loss:0.295825  train-accuracy:0.993688 valid-accuracy:0.944782
# 	Iter:136 train-loss:0.087994 valid-loss:0.292171  train-accuracy:0.994538 valid-accuracy:0.944411
# 	Iter:146 train-loss:0.082359 valid-loss:0.291772  train-accuracy:0.994918 valid-accuracy:0.945338
# 	Iter:156 train-loss:0.076981 valid-loss:0.293160  train-accuracy:0.995158 valid-accuracy:0.945524
# 	Iter:166 train-loss:0.071758 valid-loss:0.293495  train-accuracy:0.995638 valid-accuracy:0.945894
# 	Iter:176 train-loss:0.067132 valid-loss:0.296775  train-accuracy:0.995878 valid-accuracy:0.945894

# %%
# Model features
model.make_inspector().features()
# Out:
# ["Autocorrelation" (1; #0),
#  "ClusterProminence" (1; #1),
#  "ClusterShade" (1; #2),
#  "ClusterTendency" (1; #3),
#  "Contrast" (1; #4),
#  "Correlation" (1; #5),
#  "DifferenceAverage" (1; #6),
#  "DifferenceEntropy" (1; #7),
#  "DifferenceVariance" (1; #8),
#  "Id" (1; #9),
#  "Idm" (1; #10),
#  "Idmn" (1; #11),
#  "Idn" (1; #12),
#  "Imc1" (1; #13),
#  "Imc2" (1; #14),
#  "InverseVariance" (1; #15),
#  "JointAverage" (1; #16),
#  "JointEnergy" (1; #17),
#  "JointEntropy" (1; #18),
#  "MCC" (1; #19),
#  "MaximumProbability" (1; #20),
#  "SumAverage" (1; #21),
#  "SumEntropy" (1; #22),
#  "SumSquares" (1; #23)]

# %%
# Feature importance
model.make_inspector().variable_importances()
# Out:
# {'INV_MEAN_MIN_DEPTH': [("Autocorrelation" (1; #0), 0.25512420965945376),
#   ("JointAverage" (1; #16), 0.25033071964486386),
#   ("SumAverage" (1; #21), 0.214905368236485),
#   ("Correlation" (1; #5), 0.2145547601472269),
#   ("Idn" (1; #12), 0.21366799750422458),
#   ("Idmn" (1; #11), 0.20163289740755774),
#   ("ClusterShade" (1; #2), 0.19338036565491432),
#   ("InverseVariance" (1; #15), 0.19099184980172304),
#   ("DifferenceVariance" (1; #8), 0.18673005929484476),
#   ("DifferenceAverage" (1; #6), 0.1826046189169312),
#   ("Idm" (1; #10), 0.18111519669026577),
#   ("DifferenceEntropy" (1; #7), 0.17933518320018432),
#   ("MaximumProbability" (1; #20), 0.17928588414309998),
#   ("MCC" (1; #19), 0.17919907799136406),
#   ("Id" (1; #9), 0.17861206180698358),
#   ("Contrast" (1; #4), 0.17843925956609072),
#   ("SumEntropy" (1; #22), 0.17772983328212777),
#   ("JointEnergy" (1; #17), 0.17745276493498294),
#   ("Imc1" (1; #13), 0.1743354486272131),
#   ("JointEntropy" (1; #18), 0.17356302915405636),
#   ("SumSquares" (1; #23), 0.1732854098174245),
#   ("ClusterTendency" (1; #3), 0.17322502673463305),
#   ("Imc2" (1; #14), 0.17296116230621522),
#   ("ClusterProminence" (1; #1), 0.1726867149551451)],
#  'SUM_SCORE': [("Autocorrelation" (1; #0), 18026.34263190399),
#   ("Idn" (1; #12), 3063.8642218866926),
#   ("InverseVariance" (1; #15), 2041.045956633972),
#   ("JointAverage" (1; #16), 1970.3625937487593),
#   ("SumAverage" (1; #21), 1653.268530777957),
#   ("Correlation" (1; #5), 1003.7200956753952),
#   ("Idmn" (1; #11), 803.4395714927379),
#   ("DifferenceEntropy" (1; #7), 714.2509194334657),
#   ("DifferenceAverage" (1; #6), 697.3570928001251),
#   ("ClusterShade" (1; #2), 686.6519505461994),
#   ("Imc1" (1; #13), 531.9561889966201),
#   ("Idm" (1; #10), 413.8107880911828),
#   ("Id" (1; #9), 352.52336850530355),
#   ("DifferenceVariance" (1; #8), 249.93753087585685),
#   ("MaximumProbability" (1; #20), 229.9317173625155),
#   ("SumEntropy" (1; #22), 228.86752929785908),
#   ("Contrast" (1; #4), 196.575998821137),
#   ("MCC" (1; #19), 140.4014370912293),
#   ("SumSquares" (1; #23), 113.9147934107245),
#   ("JointEnergy" (1; #17), 111.05008420129695),
#   ("ClusterTendency" (1; #3), 83.80883519481758),
#   ("Imc2" (1; #14), 74.66785684700359),
#   ("ClusterProminence" (1; #1), 33.96088323977652),
#   ("JointEntropy" (1; #18), 20.702332507873884)],
#  'NUM_AS_ROOT': [("JointAverage" (1; #16), 47.0),
#   ("Autocorrelation" (1; #0), 31.0),
#   ("SumAverage" (1; #21), 23.0),
#   ("Correlation" (1; #5), 20.0),
#   ("Idmn" (1; #11), 9.0),
#   ("Idn" (1; #12), 6.0),
#   ("JointEnergy" (1; #17), 4.0),
#   ("DifferenceVariance" (1; #8), 3.0),
#   ("SumEntropy" (1; #22), 3.0),
#   ("MCC" (1; #19), 2.0),
#   ("Contrast" (1; #4), 1.0),
#   ("JointEntropy" (1; #18), 1.0)],
#  'NUM_NODES': [("Autocorrelation" (1; #0), 515.0),
#   ("Idn" (1; #12), 436.0),
#   ("Idmn" (1; #11), 283.0),
#   ("ClusterShade" (1; #2), 273.0),
#   ("JointAverage" (1; #16), 247.0),
#   ("Correlation" (1; #5), 243.0),
#   ("SumAverage" (1; #21), 236.0),
#   ("InverseVariance" (1; #15), 163.0),
#   ("DifferenceAverage" (1; #6), 157.0),
#   ("DifferenceVariance" (1; #8), 138.0),
#   ("MaximumProbability" (1; #20), 125.0),
#   ("DifferenceEntropy" (1; #7), 118.0),
#   ("MCC" (1; #19), 114.0),
#   ("Idm" (1; #10), 104.0),
#   ("Contrast" (1; #4), 102.0),
#   ("Id" (1; #9), 92.0),
#   ("SumEntropy" (1; #22), 84.0),
#   ("Imc1" (1; #13), 79.0),
#   ("JointEnergy" (1; #17), 65.0),
#   ("ClusterTendency" (1; #3), 45.0),
#   ("Imc2" (1; #14), 45.0),
#   ("SumSquares" (1; #23), 39.0),
#   ("ClusterProminence" (1; #1), 38.0),
#   ("JointEntropy" (1; #18), 26.0)]}

# %%
# Model self evaluation
model.make_inspector().evaluation()
# Out:
# Evaluation(num_examples=None, accuracy=0.9453380703926086, loss=0.29063680768013, rmse=None, ndcg=None, aucs=None, auuc=None, qini=None)

# %%
logs = model.make_inspector().training_logs()

plt.figure(figsize=(12, 4))
plt.subplot(1, 2, 1)
plt.plot([log.num_trees for log in logs], [log.evaluation.accuracy for log in logs])
plt.xlabel("Number of trees")
plt.ylabel("Accuracy (out-of-bag)")
plt.subplot(1, 2, 2)
plt.plot([log.num_trees for log in logs], [log.evaluation.loss for log in logs])
plt.xlabel("Number of trees")
plt.ylabel("Logloss (out-of-bag)")
plt.show()

# %% [markdown]
# Calculate the score of our hold-out validation dataset

# %%
predictions = model.predict(val_ds)
y_true      = validation_data["label"]

from sklearn.metrics import roc_auc_score
ROC_AUC = roc_auc_score(y_true, predictions)
print("The ROC AUC score is %.5f" % ROC_AUC )
# Out:
# 1/5 [=====>........................] - ETA: 0s
# 5/5 [==============================] - 0s 5ms/step
# The ROC AUC score is 0.99859

# %%
# Compute binary classification metrics with sklearn
import numpy as np
from sklearn.metrics import (
    accuracy_score,
    precision_score,
    recall_score,
    f1_score,
    roc_auc_score,
    average_precision_score,
    confusion_matrix,
    classification_report,
    matthews_corrcoef,
    log_loss,
    brier_score_loss,
)

# Get predictions (probabilities or class labels)
preds = model.predict(test_ds)
# If model outputs probabilities, convert to labels by threshold 0.5
if preds.ndim == 2:
    # For TFDF classification, preds may be class probabilities with shape (N, 2)
    if preds.shape[1] == 2:
        pos_probs = preds[:, 1]
    else:
        # If single-probability column (positive class)
        pos_probs = preds[:, -1]
    y_pred = (pos_probs >= 0.5).astype(int)
else:
    # Already class labels
    y_pred = preds.astype(int)
    pos_probs = None

# Ground truth labels (must be 0/1 integers)
y_true = test_data["label"].astype(int).to_numpy()

# Core metrics
metrics = {}
metrics["accuracy"] = accuracy_score(y_true, y_pred)
metrics["precision"] = precision_score(y_true, y_pred, zero_division=0)
metrics["recall"] = recall_score(y_true, y_pred, zero_division=0)
metrics["f1"] = f1_score(y_true, y_pred, zero_division=0)
metrics["mcc"] = matthews_corrcoef(y_true, y_pred)

# Probabilistic metrics (only if we have probabilities)
if pos_probs is not None:
    metrics["roc_auc"] = roc_auc_score(y_true, pos_probs)
    metrics["pr_auc"] = average_precision_score(y_true, pos_probs)
    metrics["log_loss"] = log_loss(y_true, pos_probs, labels=[0,1])
    metrics["brier_score"] = brier_score_loss(y_true, pos_probs)

# Confusion matrix and detailed report
cm = confusion_matrix(y_true, y_pred, labels=[0,1])
report = classification_report(y_true, y_pred, digits=4)

print("Sklearn binary metrics:")
for k, v in metrics.items():
    print(f"{k}: {v:.4f}")
print("\nConfusion matrix:\n", cm)
print("\nClassification report:\n", report)
# Out:
# 1/9 [==>...........................] - ETA: 0s
# 9/9 [==============================] - 0s 5ms/step
# Sklearn binary metrics:
# accuracy: 0.9521
# precision: 0.6968
# recall: 0.9162
# f1: 0.7916
# mcc: 0.7742
# roc_auc: 0.9684
# pr_auc: 0.8973
# log_loss: 0.1544
# brier_score: 0.0392
#
# Confusion matrix:
#  [[7659  352]
#  [  74  809]]
#
# Classification report:
#                precision    recall  f1-score   support
#
#            0     0.9904    0.9561    0.9729      8011
#            1     0.6968    0.9162    0.7916       883
#
#     accuracy                         0.9521      8894
#    macro avg     0.8436    0.9361    0.8823      8894
# weighted avg     0.9613    0.9521    0.9549      8894
