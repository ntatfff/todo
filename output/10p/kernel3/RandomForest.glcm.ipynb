# %%
# Import packages and modules
import numpy  as np
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow_decision_forests as tfdf

from sklearn.model_selection import train_test_split
# Out:
# 2026-09-11 03:37:10.238569: I tensorflow/core/util/port.cc:113] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2026-09-11 03:37:10.587387: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2026-09-11 03:37:16.951463: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
# Check the version of TensorFlow Decision Forests
print("Found TensorFlow Decision Forests v" + tfdf.__version__)
# Out:
# Found TensorFlow Decision Forests v1.9.1

# %%
datasetPath = "dataset/10p/all/kernel3/"

# %%
# Parameters
datasetPath = "dataset/10p/glcm/kernel3/"

# %%
# train/validation/test = 70/10/20
train_data = pd.read_csv(f"{datasetPath}dataset.train.csv")
validation_data = pd.read_csv(f"{datasetPath}dataset.validation.csv")
test_data = pd.read_csv(f"{datasetPath}dataset.test.csv")

# %%
from sklearn.utils.class_weight import compute_class_weight

# tinh class weight tren tap train
classes = np.array([0, 1])
weights = compute_class_weight(class_weight="balanced", classes=classes, y=train_data["label"])
class_weight = {0: weights[0], 1: weights[1]}

# gan sample_weight cho tung dong
train_data["sample_weight"] = train_data["label"].map(class_weight)
validation_data["sample_weight"] = validation_data["label"].map(class_weight)
test_data["sample_weight"] = test_data["label"].map(class_weight)

# Convert the dataset into a TensorFlow dataset.
train_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    train_data, label="label", weight="sample_weight"
)         
val_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    validation_data, label="label", weight="sample_weight"
)
test_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    test_data, label="label", weight="sample_weight"
)
# Out:
# 2026-09-11 03:37:29.157165: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:984] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2026-09-11 03:37:29.158886: W tensorflow/core/common_runtime/gpu/gpu_device.cc:2251] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...

# %%
import keras

# %%
# %%time

# Train a Random Forest model.
model = tfdf.keras.RandomForestModel()

# Add evaluation metrics
model.compile(
    metrics=["accuracy"]
)
model.fit(x=train_ds)

# # Train a Gradient Boosted Trees model.
# model = tfdf.keras.GradientBoostedTreesModel(num_trees=1500)
# model.fit(train_ds)
# Out:
# Use /tmp/tmp069io9t6 as temporary training directory
# Reading training dataset...
# Training dataset read in 0:00:02.683749. Found 29597 examples.
# Training model...
# [INFO 26-09-11 03:37:34.0603 UTC kernel.cc:1233] Loading model from path /tmp/tmp069io9t6/model/ with prefix fc026d0750c94a66
# Model trained in 0:00:02.295489
# Compiling model...
# [INFO 26-09-11 03:37:34.2798 UTC decision_forest.cc:734] Model loaded with 300 root(s), 192260 node(s), and 24 input feature(s).
# [INFO 26-09-11 03:37:34.2799 UTC abstract_model.cc:1362] Engine "RandomForestOptPred" built
# [INFO 26-09-11 03:37:34.2799 UTC kernel.cc:1061] Use fast generic engine
# Model compiled.
# CPU times: user 29.1 s, sys: 612 ms, total: 29.7 s
# Wall time: 8 s

# %%
# Evaluate the model
evaluate = model.evaluate(val_ds, return_dict=True)
print()

for name, value in evaluate.items():
    print(f"{name}: {value:.4f}")
# Out:
# WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 1/5 [=====>........................] - ETA: 11s - loss: 0.0000e+00 - accuracy: 0.9970
# 5/5 [==============================] - ETA: 0s - loss: 0.0000e+00 - accuracy: 0.9943
# 5/5 [==============================] - 3s 14ms/step - loss: 0.0000e+00 - accuracy: 0.9943
# loss: 0.0000
# accuracy: 0.9943

# %%
# Model Summary
model.summary()
# Out:
# Model: "random_forest_model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
# =================================================================
# Total params: 1 (1.00 Byte)
# Trainable params: 0 (0.00 Byte)
# Non-trainable params: 1 (1.00 Byte)
# _________________________________________________________________
# Type: "RANDOM_FOREST"
# Task: CLASSIFICATION
# Label: "__LABEL"
#
# Input Features (24):
# 	Autocorrelation
# 	ClusterProminence
# 	ClusterShade
# 	ClusterTendency
# 	Contrast
# 	Correlation
# 	DifferenceAverage
# 	DifferenceEntropy
# 	DifferenceVariance
# 	Id
# 	Idm
# 	Idmn
# 	Idn
# 	Imc1
# 	Imc2
# 	InverseVariance
# 	JointAverage
# 	JointEnergy
# 	JointEntropy
# 	MCC
# 	MaximumProbability
# 	SumAverage
# 	SumEntropy
# 	SumSquares
#
# Trained with weights
#
# Variable Importance: INV_MEAN_MIN_DEPTH:
#     1.    "Autocorrelation"  0.180959 ################
#     2.       "JointAverage"  0.176520 ###############
#     3.         "SumAverage"  0.163065 ############
#     4.    "InverseVariance"  0.118184 ####
#     5.        "Correlation"  0.115733 ####
#     6.                "Idn"  0.112715 ###
#     7.               "Idmn"  0.112049 ###
#     8.                "MCC"  0.110315 ###
#     9.         "SumEntropy"  0.106804 ##
#    10.  "DifferenceEntropy"  0.105109 ##
#    11.                "Idm"  0.104635 ##
#    12.               "Imc1"  0.104246 ##
#    13.                 "Id"  0.103816 ##
#    14.       "ClusterShade"  0.103212 ##
#    15.        "JointEnergy"  0.102850 ##
#    16.  "DifferenceAverage"  0.100488 #
#    17. "MaximumProbability"  0.099224 #
#    18. "DifferenceVariance"  0.099130 #
#    19.           "Contrast"  0.098382 #
#    20.               "Imc2"  0.097092 #
#    21.       "JointEntropy"  0.095818
#    22.    "ClusterTendency"  0.092020
#    23.  "ClusterProminence"  0.091879
#    24.         "SumSquares"  0.091187
#
# Variable Importance: NUM_AS_ROOT:
#     1.    "Autocorrelation" 80.000000 ################
#     2.       "JointAverage" 57.000000 ###########
#     3.         "SumAverage" 57.000000 ###########
#     4.         "SumEntropy" 30.000000 #####
#     5.        "JointEnergy" 24.000000 ####
#     6.                "MCC" 16.000000 ##
#     7.        "Correlation" 12.000000 ##
#     8.       "JointEntropy" 10.000000 #
#     9. "MaximumProbability"  5.000000
#    10.               "Imc2"  3.000000
#    11.    "ClusterTendency"  2.000000
#    12.                 "Id"  2.000000
#    13.               "Imc1"  2.000000
#
# Variable Importance: NUM_NODES:
#     1.                "Idn" 8286.000000 ################
#     2.               "Idmn" 7198.000000 ############
#     3.    "Autocorrelation" 5070.000000 #######
#     4.       "JointAverage" 5055.000000 #######
#     5.         "SumAverage" 4911.000000 ######
#     6.       "ClusterShade" 4900.000000 ######
#     7.        "Correlation" 4261.000000 ####
#     8.                "MCC" 3944.000000 ###
#     9. "DifferenceVariance" 3909.000000 ###
#    10.    "InverseVariance" 3869.000000 ###
#    11.           "Contrast" 3821.000000 ###
#    12.  "DifferenceEntropy" 3710.000000 ###
#    13.  "DifferenceAverage" 3689.000000 ###
#    14.               "Imc1" 3670.000000 ###
#    15.                "Idm" 3495.000000 ##
#    16.                 "Id" 3428.000000 ##
#    17.         "SumEntropy" 3175.000000 #
#    18. "MaximumProbability" 3146.000000 #
#    19.               "Imc2" 3089.000000 #
#    20.  "ClusterProminence" 3016.000000 #
#    21.        "JointEnergy" 2686.000000
#    22.    "ClusterTendency" 2586.000000
#    23.       "JointEntropy" 2553.000000
#    24.         "SumSquares" 2513.000000
#
# Variable Importance: SUM_SCORE:
#     1.    "Autocorrelation" 1127783.168709 ################
#     2.       "JointAverage" 1060158.501469 ##############
#     3.         "SumAverage" 982629.131258 #############
#     4.                "Idn" 359667.816898 ####
#     5.               "Idmn" 309166.974799 ###
#     6.    "InverseVariance" 212221.411025 ##
#     7.        "Correlation" 163020.988292 #
#     8.                "Idm" 147755.480021 #
#     9.  "DifferenceEntropy" 137733.761539 #
#    10.                 "Id" 132690.880503 #
#    11.                "MCC" 127960.803951 #
#    12.  "DifferenceAverage" 123944.168731 #
#    13.       "ClusterShade" 122657.621952 #
#    14.         "SumEntropy" 119877.908771 #
#    15.               "Imc1" 114026.000256 #
#    16.           "Contrast" 109068.134041
#    17. "DifferenceVariance" 105725.676094
#    18.        "JointEnergy" 93364.151926
#    19. "MaximumProbability" 90584.371336
#    20.               "Imc2" 83860.404627
#    21.       "JointEntropy" 67155.096273
#    22.  "ClusterProminence" 52585.461815
#    23.    "ClusterTendency" 49515.206128
#    24.         "SumSquares" 46434.742489
#
#
#
# Winner takes all: true
# Out-of-bag evaluation: accuracy:0.919087 logloss:0.253929
# Number of trees: 300
# Total number of nodes: 192260
#
# Number of nodes by tree:
# Count: 300 Average: 640.867 StdDev: 31.4983
# Min: 547 Max: 735 Ignored: 0
# ----------------------------------------------
# [ 547, 556)  3   1.00%   1.00% #
# [ 556, 565)  1   0.33%   1.33%
# [ 565, 575)  1   0.33%   1.67%
# [ 575, 584)  4   1.33%   3.00% #
# [ 584, 594)  9   3.00%   6.00% ##
# [ 594, 603) 10   3.33%   9.33% ##
# [ 603, 613) 31  10.33%  19.67% #######
# [ 613, 622) 33  11.00%  30.67% ########
# [ 622, 632) 23   7.67%  38.33% #####
# [ 632, 641) 29   9.67%  48.00% #######
# [ 641, 650) 30  10.00%  58.00% #######
# [ 650, 660) 44  14.67%  72.67% ##########
# [ 660, 669) 19   6.33%  79.00% ####
# [ 669, 679) 35  11.67%  90.67% ########
# [ 679, 688) 13   4.33%  95.00% ###
# [ 688, 698)  5   1.67%  96.67% #
# [ 698, 707)  3   1.00%  97.67% #
# [ 707, 717)  4   1.33%  99.00% #
# [ 717, 726)  2   0.67%  99.67%
# [ 726, 735]  1   0.33% 100.00%
#
# Depth by leafs:
# Count: 96280 Average: 10.5125 StdDev: 2.57721
# Min: 2 Max: 15 Ignored: 0
# ----------------------------------------------
# [  2,  3)     4   0.00%   0.00%
# [  3,  4)   111   0.12%   0.12%
# [  4,  5)   609   0.63%   0.75%
# [  5,  6)  1698   1.76%   2.52% #
# [  6,  7)  3733   3.88%   6.39% ###
# [  7,  8)  6579   6.83%  13.23% #####
# [  8,  9)  9289   9.65%  22.87% #######
# [  9, 10) 12030  12.49%  35.37% #########
# [ 10, 11) 13463  13.98%  49.35% ##########
# [ 11, 12) 13606  14.13%  63.48% ##########
# [ 12, 13) 11872  12.33%  75.81% #########
# [ 13, 14)  9584   9.95%  85.77% #######
# [ 14, 15)  7034   7.31%  93.07% #####
# [ 15, 15]  6668   6.93% 100.00% #####
#
# Number of training obs by leaf:
# Count: 96280 Average: 92.2216 StdDev: 326.379
# Min: 5 Max: 4982 Ignored: 0
# ----------------------------------------------
# [    5,  253) 89087  92.53%  92.53% ##########
# [  253,  502)  3072   3.19%  95.72%
# [  502,  751)  1349   1.40%  97.12%
# [  751, 1000)   736   0.76%  97.89%
# [ 1000, 1249)   441   0.46%  98.34%
# [ 1249, 1498)   283   0.29%  98.64%
# [ 1498, 1747)   243   0.25%  98.89%
# [ 1747, 1996)   215   0.22%  99.11%
# [ 1996, 2245)   226   0.23%  99.35%
# [ 2245, 2494)   161   0.17%  99.51%
# [ 2494, 2742)   122   0.13%  99.64%
# [ 2742, 2991)    86   0.09%  99.73%
# [ 2991, 3240)    69   0.07%  99.80%
# [ 3240, 3489)    57   0.06%  99.86%
# [ 3489, 3738)    36   0.04%  99.90%
# [ 3738, 3987)    32   0.03%  99.93%
# [ 3987, 4236)    32   0.03%  99.97%
# [ 4236, 4485)    13   0.01%  99.98%
# [ 4485, 4734)    12   0.01%  99.99%
# [ 4734, 4982]     8   0.01% 100.00%
#
# Attribute in nodes:
# 	8286 : Idn [NUMERICAL]
# 	7198 : Idmn [NUMERICAL]
# 	5070 : Autocorrelation [NUMERICAL]
# 	5055 : JointAverage [NUMERICAL]
# 	4911 : SumAverage [NUMERICAL]
# 	4900 : ClusterShade [NUMERICAL]
# 	4261 : Correlation [NUMERICAL]
# 	3944 : MCC [NUMERICAL]
# 	3909 : DifferenceVariance [NUMERICAL]
# 	3869 : InverseVariance [NUMERICAL]
# 	3821 : Contrast [NUMERICAL]
# 	3710 : DifferenceEntropy [NUMERICAL]
# 	3689 : DifferenceAverage [NUMERICAL]
# 	3670 : Imc1 [NUMERICAL]
# 	3495 : Idm [NUMERICAL]
# 	3428 : Id [NUMERICAL]
# 	3175 : SumEntropy [NUMERICAL]
# 	3146 : MaximumProbability [NUMERICAL]
# 	3089 : Imc2 [NUMERICAL]
# 	3016 : ClusterProminence [NUMERICAL]
# 	2686 : JointEnergy [NUMERICAL]
# 	2586 : ClusterTendency [NUMERICAL]
# 	2553 : JointEntropy [NUMERICAL]
# 	2513 : SumSquares [NUMERICAL]
#
# Attribute in nodes with depth <= 0:
# 	80 : Autocorrelation [NUMERICAL]
# 	57 : SumAverage [NUMERICAL]
# 	57 : JointAverage [NUMERICAL]
# 	30 : SumEntropy [NUMERICAL]
# 	24 : JointEnergy [NUMERICAL]
# 	16 : MCC [NUMERICAL]
# 	12 : Correlation [NUMERICAL]
# 	10 : JointEntropy [NUMERICAL]
# 	5 : MaximumProbability [NUMERICAL]
# 	3 : Imc2 [NUMERICAL]
# 	2 : Imc1 [NUMERICAL]
# 	2 : Id [NUMERICAL]
# 	2 : ClusterTendency [NUMERICAL]
#
# Attribute in nodes with depth <= 1:
# 	199 : JointAverage [NUMERICAL]
# 	170 : SumAverage [NUMERICAL]
# 	170 : Autocorrelation [NUMERICAL]
# 	46 : SumEntropy [NUMERICAL]
# 	42 : Correlation [NUMERICAL]
# 	37 : JointEnergy [NUMERICAL]
# 	37 : InverseVariance [NUMERICAL]
# 	27 : DifferenceEntropy [NUMERICAL]
# 	20 : MCC [NUMERICAL]
# 	20 : Imc1 [NUMERICAL]
# 	18 : DifferenceVariance [NUMERICAL]
# 	16 : MaximumProbability [NUMERICAL]
# 	15 : Imc2 [NUMERICAL]
# 	15 : DifferenceAverage [NUMERICAL]
# 	14 : JointEntropy [NUMERICAL]
# 	14 : Idmn [NUMERICAL]
# 	11 : Id [NUMERICAL]
# 	9 : Contrast [NUMERICAL]
# 	8 : Idn [NUMERICAL]
# 	6 : ClusterTendency [NUMERICAL]
# 	4 : Idm [NUMERICAL]
# 	2 : SumSquares [NUMERICAL]
#
# Attribute in nodes with depth <= 2:
# 	390 : JointAverage [NUMERICAL]
# 	361 : SumAverage [NUMERICAL]
# 	360 : Autocorrelation [NUMERICAL]
# 	113 : InverseVariance [NUMERICAL]
# 	110 : Correlation [NUMERICAL]
# 	78 : SumEntropy [NUMERICAL]
# 	71 : DifferenceEntropy [NUMERICAL]
# 	59 : Imc1 [NUMERICAL]
# 	57 : Idm [NUMERICAL]
# 	54 : JointEnergy [NUMERICAL]
# 	53 : MCC [NUMERICAL]
# 	53 : Id [NUMERICAL]
# 	52 : DifferenceAverage [NUMERICAL]
# 	45 : MaximumProbability [NUMERICAL]
# 	40 : ClusterShade [NUMERICAL]
# 	39 : DifferenceVariance [NUMERICAL]
# 	34 : Contrast [NUMERICAL]
# 	30 : JointEntropy [NUMERICAL]
# 	26 : Idmn [NUMERICAL]
# 	25 : Imc2 [NUMERICAL]
# 	21 : Idn [NUMERICAL]
# 	12 : ClusterTendency [NUMERICAL]
# 	9 : SumSquares [NUMERICAL]
# 	4 : ClusterProminence [NUMERICAL]
#
# Attribute in nodes with depth <= 3:
# 	619 : JointAverage [NUMERICAL]
# 	608 : Autocorrelation [NUMERICAL]
# 	578 : SumAverage [NUMERICAL]
# 	269 : Correlation [NUMERICAL]
# 	228 : InverseVariance [NUMERICAL]
# 	190 : ClusterShade [NUMERICAL]
# 	153 : Imc1 [NUMERICAL]
# 	150 : MCC [NUMERICAL]
# 	147 : Idmn [NUMERICAL]
# 	141 : Idm [NUMERICAL]
# 	139 : DifferenceEntropy [NUMERICAL]
# 	133 : Idn [NUMERICAL]
# 	131 : SumEntropy [NUMERICAL]
# 	130 : DifferenceVariance [NUMERICAL]
# 	126 : Id [NUMERICAL]
# 	110 : Contrast [NUMERICAL]
# 	102 : DifferenceAverage [NUMERICAL]
# 	91 : Imc2 [NUMERICAL]
# 	84 : JointEnergy [NUMERICAL]
# 	77 : MaximumProbability [NUMERICAL]
# 	53 : JointEntropy [NUMERICAL]
# 	45 : ClusterProminence [NUMERICAL]
# 	42 : ClusterTendency [NUMERICAL]
# 	31 : SumSquares [NUMERICAL]
#
# Attribute in nodes with depth <= 5:
# 	1304 : Autocorrelation [NUMERICAL]
# 	1279 : JointAverage [NUMERICAL]
# 	1253 : SumAverage [NUMERICAL]
# 	1023 : Idn [NUMERICAL]
# 	944 : Idmn [NUMERICAL]
# 	831 : ClusterShade [NUMERICAL]
# 	765 : Correlation [NUMERICAL]
# 	669 : InverseVariance [NUMERICAL]
# 	622 : MCC [NUMERICAL]
# 	534 : Imc1 [NUMERICAL]
# 	524 : Idm [NUMERICAL]
# 	505 : DifferenceVariance [NUMERICAL]
# 	502 : DifferenceEntropy [NUMERICAL]
# 	457 : Id [NUMERICAL]
# 	443 : DifferenceAverage [NUMERICAL]
# 	443 : Contrast [NUMERICAL]
# 	421 : Imc2 [NUMERICAL]
# 	392 : SumEntropy [NUMERICAL]
# 	315 : MaximumProbability [NUMERICAL]
# 	307 : ClusterProminence [NUMERICAL]
# 	287 : JointEnergy [NUMERICAL]
# 	248 : ClusterTendency [NUMERICAL]
# 	243 : JointEntropy [NUMERICAL]
# 	227 : SumSquares [NUMERICAL]
#
# Condition type in nodes:
# 	95980 : HigherCondition
# Condition type in nodes with depth <= 0:
# 	300 : HigherCondition
# Condition type in nodes with depth <= 1:
# 	900 : HigherCondition
# Condition type in nodes with depth <= 2:
# 	2096 : HigherCondition
# Condition type in nodes with depth <= 3:
# 	4377 : HigherCondition
# Condition type in nodes with depth <= 5:
# 	14538 : HigherCondition
# Node format: NOT_SET
#
# Training OOB:
# 	trees: 1, Out-of-bag evaluation: accuracy:0.894547 logloss:3.80092
# 	trees: 11, Out-of-bag evaluation: accuracy:0.889851 logloss:1.57997
# 	trees: 21, Out-of-bag evaluation: accuracy:0.906624 logloss:0.862885
# 	trees: 31, Out-of-bag evaluation: accuracy:0.909062 logloss:0.66599
# 	trees: 41, Out-of-bag evaluation: accuracy:0.910777 logloss:0.582557
# 	trees: 51, Out-of-bag evaluation: accuracy:0.912861 logloss:0.537612
# 	trees: 61, Out-of-bag evaluation: accuracy:0.91435 logloss:0.474719
# 	trees: 71, Out-of-bag evaluation: accuracy:0.91592 logloss:0.403349
# 	trees: 81, Out-of-bag evaluation: accuracy:0.915153 logloss:0.359673
# 	trees: 91, Out-of-bag evaluation: accuracy:0.916425 logloss:0.325887
# 	trees: 101, Out-of-bag evaluation: accuracy:0.917093 logloss:0.325881
# 	trees: 111, Out-of-bag evaluation: accuracy:0.917616 logloss:0.325948
# 	trees: 121, Out-of-bag evaluation: accuracy:0.918455 logloss:0.317167
# 	trees: 131, Out-of-bag evaluation: accuracy:0.91767 logloss:0.315773
# 	trees: 141, Out-of-bag evaluation: accuracy:0.918437 logloss:0.30789
# 	trees: 151, Out-of-bag evaluation: accuracy:0.917896 logloss:0.298663
# 	trees: 161, Out-of-bag evaluation: accuracy:0.919186 logloss:0.281774
# 	trees: 171, Out-of-bag evaluation: accuracy:0.91896 logloss:0.280851
# 	trees: 181, Out-of-bag evaluation: accuracy:0.919989 logloss:0.279836
# 	trees: 191, Out-of-bag evaluation: accuracy:0.919222 logloss:0.271691
# 	trees: 201, Out-of-bag evaluation: accuracy:0.918699 logloss:0.27127
# 	trees: 211, Out-of-bag evaluation: accuracy:0.91868 logloss:0.270251
# 	trees: 221, Out-of-bag evaluation: accuracy:0.91868 logloss:0.261958
# 	trees: 231, Out-of-bag evaluation: accuracy:0.917616 logloss:0.262068
# 	trees: 241, Out-of-bag evaluation: accuracy:0.918229 logloss:0.262014
# 	trees: 251, Out-of-bag evaluation: accuracy:0.918455 logloss:0.253827
# 	trees: 261, Out-of-bag evaluation: accuracy:0.918509 logloss:0.253888
# 	trees: 271, Out-of-bag evaluation: accuracy:0.917742 logloss:0.254117
# 	trees: 281, Out-of-bag evaluation: accuracy:0.918248 logloss:0.254401
# 	trees: 291, Out-of-bag evaluation: accuracy:0.918843 logloss:0.254078
# 	trees: 300, Out-of-bag evaluation: accuracy:0.919087 logloss:0.253929

# %%
# Model features
model.make_inspector().features()
# Out:
# ["Autocorrelation" (1; #0),
#  "ClusterProminence" (1; #1),
#  "ClusterShade" (1; #2),
#  "ClusterTendency" (1; #3),
#  "Contrast" (1; #4),
#  "Correlation" (1; #5),
#  "DifferenceAverage" (1; #6),
#  "DifferenceEntropy" (1; #7),
#  "DifferenceVariance" (1; #8),
#  "Id" (1; #9),
#  "Idm" (1; #10),
#  "Idmn" (1; #11),
#  "Idn" (1; #12),
#  "Imc1" (1; #13),
#  "Imc2" (1; #14),
#  "InverseVariance" (1; #15),
#  "JointAverage" (1; #16),
#  "JointEnergy" (1; #17),
#  "JointEntropy" (1; #18),
#  "MCC" (1; #19),
#  "MaximumProbability" (1; #20),
#  "SumAverage" (1; #21),
#  "SumEntropy" (1; #22),
#  "SumSquares" (1; #23)]

# %%
# Feature importance
model.make_inspector().variable_importances()
# Out:
# {'INV_MEAN_MIN_DEPTH': [("Autocorrelation" (1; #0), 0.1809589307456629),
#   ("JointAverage" (1; #16), 0.17652038546967638),
#   ("SumAverage" (1; #21), 0.1630647745858751),
#   ("InverseVariance" (1; #15), 0.11818397471775349),
#   ("Correlation" (1; #5), 0.11573295009390654),
#   ("Idn" (1; #12), 0.1127147843304889),
#   ("Idmn" (1; #11), 0.11204882794473993),
#   ("MCC" (1; #19), 0.11031480713223854),
#   ("SumEntropy" (1; #22), 0.10680387416922195),
#   ("DifferenceEntropy" (1; #7), 0.10510892626221362),
#   ("Idm" (1; #10), 0.10463485954204696),
#   ("Imc1" (1; #13), 0.10424631039807644),
#   ("Id" (1; #9), 0.10381599382810272),
#   ("ClusterShade" (1; #2), 0.10321166557658937),
#   ("JointEnergy" (1; #17), 0.102849522819135),
#   ("DifferenceAverage" (1; #6), 0.10048819591703827),
#   ("MaximumProbability" (1; #20), 0.099223611352036),
#   ("DifferenceVariance" (1; #8), 0.09913045791694063),
#   ("Contrast" (1; #4), 0.09838210696740216),
#   ("Imc2" (1; #14), 0.09709167606487336),
#   ("JointEntropy" (1; #18), 0.09581839696052395),
#   ("ClusterTendency" (1; #3), 0.09201958690911746),
#   ("ClusterProminence" (1; #1), 0.09187863652398778),
#   ("SumSquares" (1; #23), 0.09118667165169352)],
#  'SUM_SCORE': [("Autocorrelation" (1; #0), 1127783.1687091312),
#   ("JointAverage" (1; #16), 1060158.5014685588),
#   ("SumAverage" (1; #21), 982629.1312583485),
#   ("Idn" (1; #12), 359667.8168977278),
#   ("Idmn" (1; #11), 309166.9747990757),
#   ("InverseVariance" (1; #15), 212221.41102513432),
#   ("Correlation" (1; #5), 163020.98829158908),
#   ("Idm" (1; #10), 147755.48002126414),
#   ("DifferenceEntropy" (1; #7), 137733.76153906228),
#   ("Id" (1; #9), 132690.88050348274),
#   ("MCC" (1; #19), 127960.80395109646),
#   ("DifferenceAverage" (1; #6), 123944.16873063886),
#   ("ClusterShade" (1; #2), 122657.62195156301),
#   ("SumEntropy" (1; #22), 119877.90877078212),
#   ("Imc1" (1; #13), 114026.00025626506),
#   ("Contrast" (1; #4), 109068.13404054212),
#   ("DifferenceVariance" (1; #8), 105725.67609443715),
#   ("JointEnergy" (1; #17), 93364.15192609509),
#   ("MaximumProbability" (1; #20), 90584.37133560391),
#   ("Imc2" (1; #14), 83860.40462671588),
#   ("JointEntropy" (1; #18), 67155.09627282766),
#   ("ClusterProminence" (1; #1), 52585.46181516248),
#   ("ClusterTendency" (1; #3), 49515.20612764711),
#   ("SumSquares" (1; #23), 46434.742489468976)],
#  'NUM_AS_ROOT': [("Autocorrelation" (1; #0), 80.0),
#   ("JointAverage" (1; #16), 57.0),
#   ("SumAverage" (1; #21), 57.0),
#   ("SumEntropy" (1; #22), 30.0),
#   ("JointEnergy" (1; #17), 24.0),
#   ("MCC" (1; #19), 16.0),
#   ("Correlation" (1; #5), 12.0),
#   ("JointEntropy" (1; #18), 10.0),
#   ("MaximumProbability" (1; #20), 5.0),
#   ("Imc2" (1; #14), 3.0),
#   ("ClusterTendency" (1; #3), 2.0),
#   ("Id" (1; #9), 2.0),
#   ("Imc1" (1; #13), 2.0)],
#  'NUM_NODES': [("Idn" (1; #12), 8286.0),
#   ("Idmn" (1; #11), 7198.0),
#   ("Autocorrelation" (1; #0), 5070.0),
#   ("JointAverage" (1; #16), 5055.0),
#   ("SumAverage" (1; #21), 4911.0),
#   ("ClusterShade" (1; #2), 4900.0),
#   ("Correlation" (1; #5), 4261.0),
#   ("MCC" (1; #19), 3944.0),
#   ("DifferenceVariance" (1; #8), 3909.0),
#   ("InverseVariance" (1; #15), 3869.0),
#   ("Contrast" (1; #4), 3821.0),
#   ("DifferenceEntropy" (1; #7), 3710.0),
#   ("DifferenceAverage" (1; #6), 3689.0),
#   ("Imc1" (1; #13), 3670.0),
#   ("Idm" (1; #10), 3495.0),
#   ("Id" (1; #9), 3428.0),
#   ("SumEntropy" (1; #22), 3175.0),
#   ("MaximumProbability" (1; #20), 3146.0),
#   ("Imc2" (1; #14), 3089.0),
#   ("ClusterProminence" (1; #1), 3016.0),
#   ("JointEnergy" (1; #17), 2686.0),
#   ("ClusterTendency" (1; #3), 2586.0),
#   ("JointEntropy" (1; #18), 2553.0),
#   ("SumSquares" (1; #23), 2513.0)]}

# %%
# Model self evaluation
model.make_inspector().evaluation()
# Out:
# Evaluation(num_examples=29597, accuracy=0.9190866265796591, loss=0.25392936393528337, rmse=None, ndcg=None, aucs=None, auuc=None, qini=None)

# %%
logs = model.make_inspector().training_logs()

plt.figure(figsize=(12, 4))
plt.subplot(1, 2, 1)
plt.plot([log.num_trees for log in logs], [log.evaluation.accuracy for log in logs])
plt.xlabel("Number of trees")
plt.ylabel("Accuracy (out-of-bag)")
plt.subplot(1, 2, 2)
plt.plot([log.num_trees for log in logs], [log.evaluation.loss for log in logs])
plt.xlabel("Number of trees")
plt.ylabel("Logloss (out-of-bag)")
plt.show()

# %% [markdown]
# Calculate the score of our hold-out validation dataset

# %%
predictions = model.predict(val_ds)
y_true      = validation_data["label"]

from sklearn.metrics import roc_auc_score
ROC_AUC = roc_auc_score(y_true, predictions)
print("The ROC AUC score is %.5f" % ROC_AUC )
# Out:
# 1/5 [=====>........................] - ETA: 0s
# 5/5 [==============================] - ETA: 0s
# 5/5 [==============================] - 0s 13ms/step
# The ROC AUC score is 0.99900

# %%
# Compute binary classification metrics with sklearn
import numpy as np
from sklearn.metrics import (
    accuracy_score,
    precision_score,
    recall_score,
    f1_score,
    roc_auc_score,
    average_precision_score,
    confusion_matrix,
    classification_report,
    matthews_corrcoef,
    log_loss,
    brier_score_loss,
)

# Get predictions (probabilities or class labels)
preds = model.predict(test_ds)
# If model outputs probabilities, convert to labels by threshold 0.5
if preds.ndim == 2:
    # For TFDF classification, preds may be class probabilities with shape (N, 2)
    if preds.shape[1] == 2:
        pos_probs = preds[:, 1]
    else:
        # If single-probability column (positive class)
        pos_probs = preds[:, -1]
    y_pred = (pos_probs >= 0.5).astype(int)
else:
    # Already class labels
    y_pred = preds.astype(int)
    pos_probs = None

# Ground truth labels (must be 0/1 integers)
y_true = test_data["label"].astype(int).to_numpy()

# Core metrics
metrics = {}
metrics["accuracy"] = accuracy_score(y_true, y_pred)
metrics["precision"] = precision_score(y_true, y_pred, zero_division=0)
metrics["recall"] = recall_score(y_true, y_pred, zero_division=0)
metrics["f1"] = f1_score(y_true, y_pred, zero_division=0)
metrics["mcc"] = matthews_corrcoef(y_true, y_pred)

# Probabilistic metrics (only if we have probabilities)
if pos_probs is not None:
    metrics["roc_auc"] = roc_auc_score(y_true, pos_probs)
    metrics["pr_auc"] = average_precision_score(y_true, pos_probs)
    metrics["log_loss"] = log_loss(y_true, pos_probs, labels=[0,1])
    metrics["brier_score"] = brier_score_loss(y_true, pos_probs)

# Confusion matrix and detailed report
cm = confusion_matrix(y_true, y_pred, labels=[0,1])
report = classification_report(y_true, y_pred, digits=4)

print("Sklearn binary metrics:")
for k, v in metrics.items():
    print(f"{k}: {v:.4f}")
print("\nConfusion matrix:\n", cm)
print("\nClassification report:\n", report)
# Out:
# 1/9 [==>...........................] - ETA: 0s
# 4/9 [============>.................] - ETA: 0s
# 8/9 [=========================>....] - ETA: 0s
# 9/9 [==============================] - 0s 16ms/step
# Sklearn binary metrics:
# accuracy: 0.9720
# precision: 0.8847
# recall: 0.8256
# f1: 0.8541
# mcc: 0.8393
# roc_auc: 0.9744
# pr_auc: 0.9092
# log_loss: 0.1048
# brier_score: 0.0238
#
# Confusion matrix:
#  [[7916   95]
#  [ 154  729]]
#
# Classification report:
#                precision    recall  f1-score   support
#
#            0     0.9809    0.9881    0.9845      8011
#            1     0.8847    0.8256    0.8541       883
#
#     accuracy                         0.9720      8894
#    macro avg     0.9328    0.9069    0.9193      8894
# weighted avg     0.9714    0.9720    0.9716      8894
