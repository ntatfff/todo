# %%
# Import packages and modules
import numpy  as np
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow_decision_forests as tfdf

from sklearn.model_selection import train_test_split
# Out:
# 2026-09-11 03:37:49.975605: I tensorflow/core/util/port.cc:113] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2026-09-11 03:37:50.323688: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2026-09-11 03:37:54.742622: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
# Check the version of TensorFlow Decision Forests
print("Found TensorFlow Decision Forests v" + tfdf.__version__)
# Out:
# Found TensorFlow Decision Forests v1.9.1

# %%
datasetPath = "dataset/10p/all/kernel3/"

# %%
# Parameters
datasetPath = "dataset/10p/gldm/kernel3/"

# %%
# train/validation/test = 70/10/20
train_data = pd.read_csv(f"{datasetPath}dataset.train.csv")
validation_data = pd.read_csv(f"{datasetPath}dataset.validation.csv")
test_data = pd.read_csv(f"{datasetPath}dataset.test.csv")

# %%
from sklearn.utils.class_weight import compute_class_weight

# tinh class weight tren tap train
classes = np.array([0, 1])
weights = compute_class_weight(class_weight="balanced", classes=classes, y=train_data["label"])
class_weight = {0: weights[0], 1: weights[1]}

# gan sample_weight cho tung dong
train_data["sample_weight"] = train_data["label"].map(class_weight)
validation_data["sample_weight"] = validation_data["label"].map(class_weight)
test_data["sample_weight"] = test_data["label"].map(class_weight)

# Convert the dataset into a TensorFlow dataset.
train_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    train_data, label="label", weight="sample_weight"
)         
val_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    validation_data, label="label", weight="sample_weight"
)
test_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    test_data, label="label", weight="sample_weight"
)
# Out:
# 2026-09-11 03:38:06.892229: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:984] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2026-09-11 03:38:06.894483: W tensorflow/core/common_runtime/gpu/gpu_device.cc:2251] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...

# %%
import keras

# %%
# %%time

# Train a Random Forest model.
model = tfdf.keras.RandomForestModel()

# Add evaluation metrics
model.compile(
    metrics=["accuracy"]
)
model.fit(x=train_ds)

# # Train a Gradient Boosted Trees model.
# model = tfdf.keras.GradientBoostedTreesModel(num_trees=1500)
# model.fit(train_ds)
# Out:
# Use /tmp/tmpk6rdhwzu as temporary training directory
# Reading training dataset...
# Training dataset read in 0:00:02.529471. Found 29597 examples.
# Training model...
# [INFO 26-09-11 03:38:11.4743 UTC kernel.cc:1233] Loading model from path /tmp/tmpk6rdhwzu/model/ with prefix 752867ee6f2f44e0
# Model trained in 0:00:02.223413
# Compiling model...
# [INFO 26-09-11 03:38:11.7574 UTC decision_forest.cc:734] Model loaded with 300 root(s), 240618 node(s), and 14 input feature(s).
# [INFO 26-09-11 03:38:11.7574 UTC abstract_model.cc:1362] Engine "RandomForestOptPred" built
# [INFO 26-09-11 03:38:11.7575 UTC kernel.cc:1061] Use fast generic engine
# Model compiled.
# CPU times: user 26.7 s, sys: 521 ms, total: 27.2 s
# Wall time: 7.74 s

# %%
# Evaluate the model
evaluate = model.evaluate(val_ds, return_dict=True)
print()

for name, value in evaluate.items():
    print(f"{name}: {value:.4f}")
# Out:
# WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 1/5 [=====>........................] - ETA: 19s - loss: 0.0000e+00 - accuracy: 0.9840
# 4/5 [=======================>......] - ETA: 0s - loss: 0.0000e+00 - accuracy: 0.9872
# 5/5 [==============================] - 5s 17ms/step - loss: 0.0000e+00 - accuracy: 0.9871
# loss: 0.0000
# accuracy: 0.9871

# %%
# Model Summary
model.summary()
# Out:
# Model: "random_forest_model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
# =================================================================
# Total params: 1 (1.00 Byte)
# Trainable params: 0 (0.00 Byte)
# Non-trainable params: 1 (1.00 Byte)
# _________________________________________________________________
# Type: "RANDOM_FOREST"
# Task: CLASSIFICATION
# Label: "__LABEL"
#
# Input Features (14):
# 	DependenceEntropy
# 	DependenceNonUniformity
# 	DependenceNonUniformityNormalized
# 	DependenceVariance
# 	GrayLevelNonUniformity
# 	GrayLevelVariance
# 	HighGrayLevelEmphasis
# 	LargeDependenceEmphasis
# 	LargeDependenceHighGrayLevelEmphasis
# 	LargeDependenceLowGrayLevelEmphasis
# 	LowGrayLevelEmphasis
# 	SmallDependenceEmphasis
# 	SmallDependenceHighGrayLevelEmphasis
# 	SmallDependenceLowGrayLevelEmphasis
#
# Trained with weights
#
# Variable Importance: INV_MEAN_MIN_DEPTH:
#     1.                "HighGrayLevelEmphasis"  0.234360 ################
#     2. "LargeDependenceHighGrayLevelEmphasis"  0.210512 #############
#     3.                 "LowGrayLevelEmphasis"  0.175526 #########
#     4. "SmallDependenceHighGrayLevelEmphasis"  0.151339 ######
#     5.  "SmallDependenceLowGrayLevelEmphasis"  0.138085 #####
#     6.                    "DependenceEntropy"  0.134535 ####
#     7.  "LargeDependenceLowGrayLevelEmphasis"  0.114368 ##
#     8.               "GrayLevelNonUniformity"  0.110567 #
#     9.                    "GrayLevelVariance"  0.100402
#    10.              "SmallDependenceEmphasis"  0.097809
#    11.              "LargeDependenceEmphasis"  0.096839
#    12.                   "DependenceVariance"  0.094661
#    13.              "DependenceNonUniformity"  0.093818
#    14.    "DependenceNonUniformityNormalized"  0.093418
#
# Variable Importance: NUM_AS_ROOT:
#     1.                "HighGrayLevelEmphasis" 88.000000 ################
#     2.                 "LowGrayLevelEmphasis" 86.000000 ###############
#     3. "SmallDependenceHighGrayLevelEmphasis" 53.000000 #########
#     4. "LargeDependenceHighGrayLevelEmphasis" 37.000000 ######
#     5.  "SmallDependenceLowGrayLevelEmphasis" 18.000000 ##
#     6.  "LargeDependenceLowGrayLevelEmphasis" 11.000000 #
#     7.               "GrayLevelNonUniformity"  4.000000
#     8.                    "DependenceEntropy"  3.000000
#
# Variable Importance: NUM_NODES:
#     1.                    "DependenceEntropy" 11029.000000 ################
#     2. "LargeDependenceHighGrayLevelEmphasis" 10203.000000 #############
#     3.                "HighGrayLevelEmphasis" 10153.000000 #############
#     4.  "SmallDependenceLowGrayLevelEmphasis" 9731.000000 ###########
#     5. "SmallDependenceHighGrayLevelEmphasis" 9536.000000 ###########
#     6.               "GrayLevelNonUniformity" 9502.000000 ##########
#     7.                    "GrayLevelVariance" 9009.000000 #########
#     8.                 "LowGrayLevelEmphasis" 8846.000000 ########
#     9.  "LargeDependenceLowGrayLevelEmphasis" 8041.000000 ######
#    10.              "SmallDependenceEmphasis" 7886.000000 #####
#    11.                   "DependenceVariance" 7324.000000 ###
#    12.              "LargeDependenceEmphasis" 6486.000000 #
#    13.              "DependenceNonUniformity" 6248.000000
#    14.    "DependenceNonUniformityNormalized" 6165.000000
#
# Variable Importance: SUM_SCORE:
#     1.                "HighGrayLevelEmphasis" 1238834.551829 ################
#     2.                 "LowGrayLevelEmphasis" 913491.705961 ###########
#     3. "LargeDependenceHighGrayLevelEmphasis" 837904.390342 ##########
#     4. "SmallDependenceHighGrayLevelEmphasis" 668752.357925 #######
#     5.  "SmallDependenceLowGrayLevelEmphasis" 410350.615982 ####
#     6.                    "DependenceEntropy" 358816.885274 ###
#     7.  "LargeDependenceLowGrayLevelEmphasis" 262273.894587 ##
#     8.               "GrayLevelNonUniformity" 222114.654258 #
#     9.                    "GrayLevelVariance" 166727.468495
#    10.              "SmallDependenceEmphasis" 145188.008893
#    11.              "LargeDependenceEmphasis" 129629.382727
#    12.                   "DependenceVariance" 122950.357582
#    13.    "DependenceNonUniformityNormalized" 112942.268596
#    14.              "DependenceNonUniformity" 112264.732220
#
#
#
# Winner takes all: true
# Out-of-bag evaluation: accuracy:0.86456 logloss:0.44627
# Number of trees: 300
# Total number of nodes: 240618
#
# Number of nodes by tree:
# Count: 300 Average: 802.06 StdDev: 42.1832
# Min: 655 Max: 911 Ignored: 0
# ----------------------------------------------
# [ 655, 667)  1   0.33%   0.33%
# [ 667, 680)  0   0.00%   0.33%
# [ 680, 693)  1   0.33%   0.67%
# [ 693, 706)  4   1.33%   2.00% #
# [ 706, 719)  1   0.33%   2.33%
# [ 719, 732)  9   3.00%   5.33% ##
# [ 732, 744) 12   4.00%   9.33% ###
# [ 744, 757) 11   3.67%  13.00% ###
# [ 757, 770) 26   8.67%  21.67% #######
# [ 770, 783) 27   9.00%  30.67% #######
# [ 783, 796) 39  13.00%  43.67% ##########
# [ 796, 809) 32  10.67%  54.33% ########
# [ 809, 822) 37  12.33%  66.67% #########
# [ 822, 834) 25   8.33%  75.00% ######
# [ 834, 847) 28   9.33%  84.33% #######
# [ 847, 860) 27   9.00%  93.33% #######
# [ 860, 873) 11   3.67%  97.00% ###
# [ 873, 886)  6   2.00%  99.00% ##
# [ 886, 899)  1   0.33%  99.33%
# [ 899, 911]  2   0.67% 100.00% #
#
# Depth by leafs:
# Count: 120459 Average: 11.1353 StdDev: 2.68044
# Min: 2 Max: 15 Ignored: 0
# ----------------------------------------------
# [  2,  3)     1   0.00%   0.00%
# [  3,  4)    96   0.08%   0.08%
# [  4,  5)   614   0.51%   0.59%
# [  5,  6)  1754   1.46%   2.05% #
# [  6,  7)  3699   3.07%   5.12% ##
# [  7,  8)  6193   5.14%  10.26% ####
# [  8,  9)  9382   7.79%  18.05% ######
# [  9, 10) 12018   9.98%  28.02% ########
# [ 10, 11) 14432  11.98%  40.00% #########
# [ 11, 12) 15431  12.81%  52.81% ##########
# [ 12, 13) 15279  12.68%  65.50% ##########
# [ 13, 14) 13828  11.48%  76.98% #########
# [ 14, 15) 12084  10.03%  87.01% ########
# [ 15, 15] 15648  12.99% 100.00% ##########
#
# Number of training obs by leaf:
# Count: 120459 Average: 73.7106 StdDev: 323.556
# Min: 5 Max: 6981 Ignored: 0
# ----------------------------------------------
# [    5,  353) 115716  96.06%  96.06% ##########
# [  353,  702)   2326   1.93%  97.99%
# [  702, 1051)    756   0.63%  98.62%
# [ 1051, 1400)    404   0.34%  98.96%
# [ 1400, 1749)    274   0.23%  99.18%
# [ 1749, 2098)    183   0.15%  99.34%
# [ 2098, 2446)    130   0.11%  99.44%
# [ 2446, 2795)    120   0.10%  99.54%
# [ 2795, 3144)    106   0.09%  99.63%
# [ 3144, 3493)    124   0.10%  99.73%
# [ 3493, 3842)     95   0.08%  99.81%
# [ 3842, 4191)     83   0.07%  99.88%
# [ 4191, 4540)     52   0.04%  99.93%
# [ 4540, 4888)     34   0.03%  99.95%
# [ 4888, 5237)     19   0.02%  99.97%
# [ 5237, 5586)     17   0.01%  99.98%
# [ 5586, 5935)     11   0.01%  99.99%
# [ 5935, 6284)      3   0.00% 100.00%
# [ 6284, 6633)      3   0.00% 100.00%
# [ 6633, 6981]      3   0.00% 100.00%
#
# Attribute in nodes:
# 	11029 : DependenceEntropy [NUMERICAL]
# 	10203 : LargeDependenceHighGrayLevelEmphasis [NUMERICAL]
# 	10153 : HighGrayLevelEmphasis [NUMERICAL]
# 	9731 : SmallDependenceLowGrayLevelEmphasis [NUMERICAL]
# 	9536 : SmallDependenceHighGrayLevelEmphasis [NUMERICAL]
# 	9502 : GrayLevelNonUniformity [NUMERICAL]
# 	9009 : GrayLevelVariance [NUMERICAL]
# 	8846 : LowGrayLevelEmphasis [NUMERICAL]
# 	8041 : LargeDependenceLowGrayLevelEmphasis [NUMERICAL]
# 	7886 : SmallDependenceEmphasis [NUMERICAL]
# 	7324 : DependenceVariance [NUMERICAL]
# 	6486 : LargeDependenceEmphasis [NUMERICAL]
# 	6248 : DependenceNonUniformity [NUMERICAL]
# 	6165 : DependenceNonUniformityNormalized [NUMERICAL]
#
# Attribute in nodes with depth <= 0:
# 	88 : HighGrayLevelEmphasis [NUMERICAL]
# 	86 : LowGrayLevelEmphasis [NUMERICAL]
# 	53 : SmallDependenceHighGrayLevelEmphasis [NUMERICAL]
# 	37 : LargeDependenceHighGrayLevelEmphasis [NUMERICAL]
# 	18 : SmallDependenceLowGrayLevelEmphasis [NUMERICAL]
# 	11 : LargeDependenceLowGrayLevelEmphasis [NUMERICAL]
# 	4 : GrayLevelNonUniformity [NUMERICAL]
# 	3 : DependenceEntropy [NUMERICAL]
#
# Attribute in nodes with depth <= 1:
# 	243 : HighGrayLevelEmphasis [NUMERICAL]
# 	181 : LowGrayLevelEmphasis [NUMERICAL]
# 	168 : LargeDependenceHighGrayLevelEmphasis [NUMERICAL]
# 	111 : SmallDependenceHighGrayLevelEmphasis [NUMERICAL]
# 	108 : SmallDependenceLowGrayLevelEmphasis [NUMERICAL]
# 	49 : LargeDependenceLowGrayLevelEmphasis [NUMERICAL]
# 	15 : GrayLevelNonUniformity [NUMERICAL]
# 	13 : DependenceEntropy [NUMERICAL]
# 	5 : SmallDependenceEmphasis [NUMERICAL]
# 	4 : DependenceNonUniformity [NUMERICAL]
# 	2 : LargeDependenceEmphasis [NUMERICAL]
# 	1 : GrayLevelVariance [NUMERICAL]
#
# Attribute in nodes with depth <= 2:
# 	536 : HighGrayLevelEmphasis [NUMERICAL]
# 	370 : LargeDependenceHighGrayLevelEmphasis [NUMERICAL]
# 	343 : LowGrayLevelEmphasis [NUMERICAL]
# 	233 : SmallDependenceLowGrayLevelEmphasis [NUMERICAL]
# 	219 : SmallDependenceHighGrayLevelEmphasis [NUMERICAL]
# 	116 : LargeDependenceLowGrayLevelEmphasis [NUMERICAL]
# 	107 : DependenceEntropy [NUMERICAL]
# 	64 : GrayLevelNonUniformity [NUMERICAL]
# 	33 : SmallDependenceEmphasis [NUMERICAL]
# 	22 : LargeDependenceEmphasis [NUMERICAL]
# 	21 : GrayLevelVariance [NUMERICAL]
# 	16 : DependenceNonUniformity [NUMERICAL]
# 	12 : DependenceVariance [NUMERICAL]
# 	7 : DependenceNonUniformityNormalized [NUMERICAL]
#
# Attribute in nodes with depth <= 3:
# 	931 : HighGrayLevelEmphasis [NUMERICAL]
# 	675 : LargeDependenceHighGrayLevelEmphasis [NUMERICAL]
# 	563 : LowGrayLevelEmphasis [NUMERICAL]
# 	419 : SmallDependenceLowGrayLevelEmphasis [NUMERICAL]
# 	397 : SmallDependenceHighGrayLevelEmphasis [NUMERICAL]
# 	360 : DependenceEntropy [NUMERICAL]
# 	264 : GrayLevelNonUniformity [NUMERICAL]
# 	248 : LargeDependenceLowGrayLevelEmphasis [NUMERICAL]
# 	157 : GrayLevelVariance [NUMERICAL]
# 	95 : SmallDependenceEmphasis [NUMERICAL]
# 	89 : LargeDependenceEmphasis [NUMERICAL]
# 	79 : DependenceVariance [NUMERICAL]
# 	64 : DependenceNonUniformityNormalized [NUMERICAL]
# 	60 : DependenceNonUniformity [NUMERICAL]
#
# Attribute in nodes with depth <= 5:
# 	2071 : HighGrayLevelEmphasis [NUMERICAL]
# 	1672 : LargeDependenceHighGrayLevelEmphasis [NUMERICAL]
# 	1480 : DependenceEntropy [NUMERICAL]
# 	1408 : LowGrayLevelEmphasis [NUMERICAL]
# 	1317 : SmallDependenceLowGrayLevelEmphasis [NUMERICAL]
# 	1158 : SmallDependenceHighGrayLevelEmphasis [NUMERICAL]
# 	1107 : GrayLevelNonUniformity [NUMERICAL]
# 	873 : GrayLevelVariance [NUMERICAL]
# 	868 : LargeDependenceLowGrayLevelEmphasis [NUMERICAL]
# 	621 : SmallDependenceEmphasis [NUMERICAL]
# 	581 : LargeDependenceEmphasis [NUMERICAL]
# 	540 : DependenceVariance [NUMERICAL]
# 	471 : DependenceNonUniformity [NUMERICAL]
# 	450 : DependenceNonUniformityNormalized [NUMERICAL]
#
# Condition type in nodes:
# 	120159 : HigherCondition
# Condition type in nodes with depth <= 0:
# 	300 : HigherCondition
# Condition type in nodes with depth <= 1:
# 	900 : HigherCondition
# Condition type in nodes with depth <= 2:
# 	2099 : HigherCondition
# Condition type in nodes with depth <= 3:
# 	4401 : HigherCondition
# Condition type in nodes with depth <= 5:
# 	14617 : HigherCondition
# Node format: NOT_SET
#
# Training OOB:
# 	trees: 1, Out-of-bag evaluation: accuracy:0.859008 logloss:5.08188
# 	trees: 11, Out-of-bag evaluation: accuracy:0.847839 logloss:2.4226
# 	trees: 21, Out-of-bag evaluation: accuracy:0.85418 logloss:1.52081
# 	trees: 31, Out-of-bag evaluation: accuracy:0.859289 logloss:1.20779
# 	trees: 41, Out-of-bag evaluation: accuracy:0.85781 logloss:0.985284
# 	trees: 51, Out-of-bag evaluation: accuracy:0.861482 logloss:0.927921
# 	trees: 61, Out-of-bag evaluation: accuracy:0.860201 logloss:0.85906
# 	trees: 71, Out-of-bag evaluation: accuracy:0.861879 logloss:0.777852
# 	trees: 81, Out-of-bag evaluation: accuracy:0.862285 logloss:0.733497
# 	trees: 91, Out-of-bag evaluation: accuracy:0.862565 logloss:0.672288
# 	trees: 101, Out-of-bag evaluation: accuracy:0.86326 logloss:0.631144
# 	trees: 111, Out-of-bag evaluation: accuracy:0.863864 logloss:0.613197
# 	trees: 121, Out-of-bag evaluation: accuracy:0.862403 logloss:0.596361
# 	trees: 131, Out-of-bag evaluation: accuracy:0.864135 logloss:0.578872
# 	trees: 141, Out-of-bag evaluation: accuracy:0.86391 logloss:0.569821
# 	trees: 151, Out-of-bag evaluation: accuracy:0.863729 logloss:0.552938
# 	trees: 161, Out-of-bag evaluation: accuracy:0.864153 logloss:0.553613
# 	trees: 171, Out-of-bag evaluation: accuracy:0.865029 logloss:0.545752
# 	trees: 181, Out-of-bag evaluation: accuracy:0.866039 logloss:0.528641
# 	trees: 191, Out-of-bag evaluation: accuracy:0.864731 logloss:0.527943
# 	trees: 201, Out-of-bag evaluation: accuracy:0.865381 logloss:0.528489
# 	trees: 211, Out-of-bag evaluation: accuracy:0.866166 logloss:0.528526
# 	trees: 221, Out-of-bag evaluation: accuracy:0.866111 logloss:0.511703
# 	trees: 231, Out-of-bag evaluation: accuracy:0.865489 logloss:0.504105
# 	trees: 241, Out-of-bag evaluation: accuracy:0.865606 logloss:0.504106
# 	trees: 251, Out-of-bag evaluation: accuracy:0.86566 logloss:0.4956
# 	trees: 261, Out-of-bag evaluation: accuracy:0.865678 logloss:0.48701
# 	trees: 271, Out-of-bag evaluation: accuracy:0.866463 logloss:0.470723
# 	trees: 281, Out-of-bag evaluation: accuracy:0.865751 logloss:0.470807
# 	trees: 291, Out-of-bag evaluation: accuracy:0.86557 logloss:0.454444
# 	trees: 300, Out-of-bag evaluation: accuracy:0.86456 logloss:0.44627

# %%
# Model features
model.make_inspector().features()
# Out:
# ["DependenceEntropy" (1; #0),
#  "DependenceNonUniformity" (1; #1),
#  "DependenceNonUniformityNormalized" (1; #2),
#  "DependenceVariance" (1; #3),
#  "GrayLevelNonUniformity" (1; #4),
#  "GrayLevelVariance" (1; #5),
#  "HighGrayLevelEmphasis" (1; #6),
#  "LargeDependenceEmphasis" (1; #7),
#  "LargeDependenceHighGrayLevelEmphasis" (1; #8),
#  "LargeDependenceLowGrayLevelEmphasis" (1; #9),
#  "LowGrayLevelEmphasis" (1; #10),
#  "SmallDependenceEmphasis" (1; #11),
#  "SmallDependenceHighGrayLevelEmphasis" (1; #12),
#  "SmallDependenceLowGrayLevelEmphasis" (1; #13)]

# %%
# Feature importance
model.make_inspector().variable_importances()
# Out:
# {'INV_MEAN_MIN_DEPTH': [("HighGrayLevelEmphasis" (1; #6), 0.23435956710551306),
#   ("LargeDependenceHighGrayLevelEmphasis" (1; #8), 0.21051199593534362),
#   ("LowGrayLevelEmphasis" (1; #10), 0.17552625031628455),
#   ("SmallDependenceHighGrayLevelEmphasis" (1; #12), 0.15133929409291336),
#   ("SmallDependenceLowGrayLevelEmphasis" (1; #13), 0.13808488864154705),
#   ("DependenceEntropy" (1; #0), 0.13453498564971217),
#   ("LargeDependenceLowGrayLevelEmphasis" (1; #9), 0.11436755526167677),
#   ("GrayLevelNonUniformity" (1; #4), 0.11056684510738501),
#   ("GrayLevelVariance" (1; #5), 0.10040214342840083),
#   ("SmallDependenceEmphasis" (1; #11), 0.09780861201605477),
#   ("LargeDependenceEmphasis" (1; #7), 0.09683894708230097),
#   ("DependenceVariance" (1; #3), 0.0946607399191853),
#   ("DependenceNonUniformity" (1; #1), 0.09381820298158922),
#   ("DependenceNonUniformityNormalized" (1; #2), 0.09341774531431785)],
#  'SUM_SCORE': [("HighGrayLevelEmphasis" (1; #6), 1238834.55182904),
#   ("LowGrayLevelEmphasis" (1; #10), 913491.7059606197),
#   ("LargeDependenceHighGrayLevelEmphasis" (1; #8), 837904.3903415456),
#   ("SmallDependenceHighGrayLevelEmphasis" (1; #12), 668752.3579253406),
#   ("SmallDependenceLowGrayLevelEmphasis" (1; #13), 410350.6159819928),
#   ("DependenceEntropy" (1; #0), 358816.88527413993),
#   ("LargeDependenceLowGrayLevelEmphasis" (1; #9), 262273.8945867854),
#   ("GrayLevelNonUniformity" (1; #4), 222114.65425812532),
#   ("GrayLevelVariance" (1; #5), 166727.4684948108),
#   ("SmallDependenceEmphasis" (1; #11), 145188.008893108),
#   ("LargeDependenceEmphasis" (1; #7), 129629.38272679265),
#   ("DependenceVariance" (1; #3), 122950.35758211644),
#   ("DependenceNonUniformityNormalized" (1; #2), 112942.26859640282),
#   ("DependenceNonUniformity" (1; #1), 112264.7322200323)],
#  'NUM_AS_ROOT': [("HighGrayLevelEmphasis" (1; #6), 88.0),
#   ("LowGrayLevelEmphasis" (1; #10), 86.0),
#   ("SmallDependenceHighGrayLevelEmphasis" (1; #12), 53.0),
#   ("LargeDependenceHighGrayLevelEmphasis" (1; #8), 37.0),
#   ("SmallDependenceLowGrayLevelEmphasis" (1; #13), 18.0),
#   ("LargeDependenceLowGrayLevelEmphasis" (1; #9), 11.0),
#   ("GrayLevelNonUniformity" (1; #4), 4.0),
#   ("DependenceEntropy" (1; #0), 3.0)],
#  'NUM_NODES': [("DependenceEntropy" (1; #0), 11029.0),
#   ("LargeDependenceHighGrayLevelEmphasis" (1; #8), 10203.0),
#   ("HighGrayLevelEmphasis" (1; #6), 10153.0),
#   ("SmallDependenceLowGrayLevelEmphasis" (1; #13), 9731.0),
#   ("SmallDependenceHighGrayLevelEmphasis" (1; #12), 9536.0),
#   ("GrayLevelNonUniformity" (1; #4), 9502.0),
#   ("GrayLevelVariance" (1; #5), 9009.0),
#   ("LowGrayLevelEmphasis" (1; #10), 8846.0),
#   ("LargeDependenceLowGrayLevelEmphasis" (1; #9), 8041.0),
#   ("SmallDependenceEmphasis" (1; #11), 7886.0),
#   ("DependenceVariance" (1; #3), 7324.0),
#   ("LargeDependenceEmphasis" (1; #7), 6486.0),
#   ("DependenceNonUniformity" (1; #1), 6248.0),
#   ("DependenceNonUniformityNormalized" (1; #2), 6165.0)]}

# %%
# Model self evaluation
model.make_inspector().evaluation()
# Out:
# Evaluation(num_examples=29597, accuracy=0.8645595345255452, loss=0.4462696317484949, rmse=None, ndcg=None, aucs=None, auuc=None, qini=None)

# %%
logs = model.make_inspector().training_logs()

plt.figure(figsize=(12, 4))
plt.subplot(1, 2, 1)
plt.plot([log.num_trees for log in logs], [log.evaluation.accuracy for log in logs])
plt.xlabel("Number of trees")
plt.ylabel("Accuracy (out-of-bag)")
plt.subplot(1, 2, 2)
plt.plot([log.num_trees for log in logs], [log.evaluation.loss for log in logs])
plt.xlabel("Number of trees")
plt.ylabel("Logloss (out-of-bag)")
plt.show()

# %% [markdown]
# Calculate the score of our hold-out validation dataset

# %%
predictions = model.predict(val_ds)
y_true      = validation_data["label"]

from sklearn.metrics import roc_auc_score
ROC_AUC = roc_auc_score(y_true, predictions)
print("The ROC AUC score is %.5f" % ROC_AUC )
# Out:
# 1/5 [=====>........................] - ETA: 0s
# 4/5 [=======================>......] - ETA: 0s
# 5/5 [==============================] - 0s 15ms/step
# The ROC AUC score is 0.99598

# %%
# Compute binary classification metrics with sklearn
import numpy as np
from sklearn.metrics import (
    accuracy_score,
    precision_score,
    recall_score,
    f1_score,
    roc_auc_score,
    average_precision_score,
    confusion_matrix,
    classification_report,
    matthews_corrcoef,
    log_loss,
    brier_score_loss,
)

# Get predictions (probabilities or class labels)
preds = model.predict(test_ds)
# If model outputs probabilities, convert to labels by threshold 0.5
if preds.ndim == 2:
    # For TFDF classification, preds may be class probabilities with shape (N, 2)
    if preds.shape[1] == 2:
        pos_probs = preds[:, 1]
    else:
        # If single-probability column (positive class)
        pos_probs = preds[:, -1]
    y_pred = (pos_probs >= 0.5).astype(int)
else:
    # Already class labels
    y_pred = preds.astype(int)
    pos_probs = None

# Ground truth labels (must be 0/1 integers)
y_true = test_data["label"].astype(int).to_numpy()

# Core metrics
metrics = {}
metrics["accuracy"] = accuracy_score(y_true, y_pred)
metrics["precision"] = precision_score(y_true, y_pred, zero_division=0)
metrics["recall"] = recall_score(y_true, y_pred, zero_division=0)
metrics["f1"] = f1_score(y_true, y_pred, zero_division=0)
metrics["mcc"] = matthews_corrcoef(y_true, y_pred)

# Probabilistic metrics (only if we have probabilities)
if pos_probs is not None:
    metrics["roc_auc"] = roc_auc_score(y_true, pos_probs)
    metrics["pr_auc"] = average_precision_score(y_true, pos_probs)
    metrics["log_loss"] = log_loss(y_true, pos_probs, labels=[0,1])
    metrics["brier_score"] = brier_score_loss(y_true, pos_probs)

# Confusion matrix and detailed report
cm = confusion_matrix(y_true, y_pred, labels=[0,1])
report = classification_report(y_true, y_pred, digits=4)

print("Sklearn binary metrics:")
for k, v in metrics.items():
    print(f"{k}: {v:.4f}")
print("\nConfusion matrix:\n", cm)
print("\nClassification report:\n", report)
# Out:
# 1/9 [==>...........................] - ETA: 0s
# 4/9 [============>.................] - ETA: 0s
# 7/9 [======================>.......] - ETA: 0s
# 9/9 [==============================] - 0s 19ms/step
# Sklearn binary metrics:
# accuracy: 0.9668
# precision: 0.8973
# recall: 0.7520
# f1: 0.8182
# mcc: 0.8039
# roc_auc: 0.9642
# pr_auc: 0.8716
# log_loss: 0.1241
# brier_score: 0.0275
#
# Confusion matrix:
#  [[7935   76]
#  [ 219  664]]
#
# Classification report:
#                precision    recall  f1-score   support
#
#            0     0.9731    0.9905    0.9818      8011
#            1     0.8973    0.7520    0.8182       883
#
#     accuracy                         0.9668      8894
#    macro avg     0.9352    0.8712    0.9000      8894
# weighted avg     0.9656    0.9668    0.9655      8894
