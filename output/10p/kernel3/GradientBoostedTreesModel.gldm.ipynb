# %%
# Import packages and modules
import numpy  as np
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow_decision_forests as tfdf

from sklearn.model_selection import train_test_split
# Out:
# 2026-09-10 09:46:12.195740: I tensorflow/core/util/port.cc:113] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2026-09-10 09:46:12.566868: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2026-09-10 09:46:17.282025: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
# Check the version of TensorFlow Decision Forests
print("Found TensorFlow Decision Forests v" + tfdf.__version__)
# Out:
# Found TensorFlow Decision Forests v1.9.1

# %%
datasetPath = "dataset/10p/all/kernel3/"

# %%
# Parameters
datasetPath = "dataset/10p/gldm/kernel3/"

# %%
# train/validation/test = 70/10/20
train_data = pd.read_csv(f"{datasetPath}dataset.train.csv")
validation_data = pd.read_csv(f"{datasetPath}dataset.validation.csv")
test_data = pd.read_csv(f"{datasetPath}dataset.test.csv")

# %%
from sklearn.utils.class_weight import compute_class_weight

# tinh class weight tren tap train
classes = np.array([0, 1])
weights = compute_class_weight(class_weight="balanced", classes=classes, y=train_data["label"])
class_weight = {0: weights[0], 1: weights[1]}

# gan sample_weight cho tung dong
train_data["sample_weight"] = train_data["label"].map(class_weight)
validation_data["sample_weight"] = validation_data["label"].map(class_weight)
test_data["sample_weight"] = test_data["label"].map(class_weight)

# Convert the dataset into a TensorFlow dataset.
train_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    train_data, label="label", weight="sample_weight"
)         
val_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    validation_data, label="label", weight="sample_weight"
)
test_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    test_data, label="label", weight="sample_weight"
)
# Out:
# 2026-09-10 09:46:30.661829: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:984] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2026-09-10 09:46:30.663480: W tensorflow/core/common_runtime/gpu/gpu_device.cc:2251] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...

# %%
import keras

# %%
# %%time

# Train a Gradient Boosted Trees model.
model = tfdf.keras.GradientBoostedTreesModel()

# Add evaluation metrics
model.compile(
    metrics=["accuracy"]
)
model.fit(x=train_ds)

# # Train a Gradient Boosted Trees model.
# model = tfdf.keras.GradientBoostedTreesModel(num_trees=1500)
# model.fit(train_ds)
# Out:
# Use /tmp/tmprpb5oelk as temporary training directory
# Reading training dataset...
# [WARNING 26-09-10 09:46:30.8024 UTC gradient_boosted_trees.cc:1840] "goss_alpha" set but "sampling_method" not equal to "GOSS".
# [WARNING 26-09-10 09:46:30.8026 UTC gradient_boosted_trees.cc:1851] "goss_beta" set but "sampling_method" not equal to "GOSS".
# [WARNING 26-09-10 09:46:30.8026 UTC gradient_boosted_trees.cc:1865] "selective_gradient_boosting_ratio" set but "sampling_method" not equal to "SELGB".
# Training dataset read in 0:00:02.663185. Found 29597 examples.
# Training model...
# Model trained in 0:00:01.851608
# Compiling model...
# [INFO 26-09-10 09:46:35.3467 UTC kernel.cc:1233] Loading model from path /tmp/tmprpb5oelk/model/ with prefix 855218a7ee3f4953
# [INFO 26-09-10 09:46:35.3508 UTC quick_scorer_extended.cc:911] The binary was compiled without AVX2 support, but your CPU supports it. Enable it for faster model inference.
# [INFO 26-09-10 09:46:35.3510 UTC abstract_model.cc:1362] Engine "GradientBoostedTreesQuickScorerExtended" built
# [INFO 26-09-10 09:46:35.3510 UTC kernel.cc:1061] Use fast generic engine
# Model compiled.
# CPU times: user 15.7 s, sys: 705 ms, total: 16.4 s
# Wall time: 7.69 s

# %%
# Evaluate the model
evaluate = model.evaluate(val_ds, return_dict=True)
print()

for name, value in evaluate.items():
    print(f"{name}: {value:.4f}")
# Out:
# WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 1/5 [=====>........................] - ETA: 12s - loss: 0.0000e+00 - accuracy: 0.9630
# 5/5 [==============================] - 3s 4ms/step - loss: 0.0000e+00 - accuracy: 0.9658
# loss: 0.0000
# accuracy: 0.9658

# %%
# Model Summary
model.summary()
# Out:
# Model: "gradient_boosted_trees_model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
# =================================================================
# Total params: 1 (1.00 Byte)
# Trainable params: 0 (0.00 Byte)
# Non-trainable params: 1 (1.00 Byte)
# _________________________________________________________________
# Type: "GRADIENT_BOOSTED_TREES"
# Task: CLASSIFICATION
# Label: "__LABEL"
#
# Input Features (14):
# 	DependenceEntropy
# 	DependenceNonUniformity
# 	DependenceNonUniformityNormalized
# 	DependenceVariance
# 	GrayLevelNonUniformity
# 	GrayLevelVariance
# 	HighGrayLevelEmphasis
# 	LargeDependenceEmphasis
# 	LargeDependenceHighGrayLevelEmphasis
# 	LargeDependenceLowGrayLevelEmphasis
# 	LowGrayLevelEmphasis
# 	SmallDependenceEmphasis
# 	SmallDependenceHighGrayLevelEmphasis
# 	SmallDependenceLowGrayLevelEmphasis
#
# Trained with weights
#
# Variable Importance: INV_MEAN_MIN_DEPTH:
#     1.                "HighGrayLevelEmphasis"  0.498987 ################
#     2. "LargeDependenceHighGrayLevelEmphasis"  0.313201 ######
#     3.                    "DependenceEntropy"  0.213537 ##
#     4.                 "LowGrayLevelEmphasis"  0.193073 #
#     5.  "SmallDependenceLowGrayLevelEmphasis"  0.189429
#     6. "SmallDependenceHighGrayLevelEmphasis"  0.186259
#     7.  "LargeDependenceLowGrayLevelEmphasis"  0.186155
#     8.               "GrayLevelNonUniformity"  0.185750
#     9.                   "DependenceVariance"  0.184215
#    10.              "SmallDependenceEmphasis"  0.179051
#    11.                    "GrayLevelVariance"  0.177486
#    12.              "LargeDependenceEmphasis"  0.174429
#    13.              "DependenceNonUniformity"  0.171805
#    14.    "DependenceNonUniformityNormalized"  0.170697
#
# Variable Importance: NUM_AS_ROOT:
#     1.                "HighGrayLevelEmphasis" 37.000000 ################
#     2. "LargeDependenceHighGrayLevelEmphasis"  8.000000 ##
#     3.                 "LowGrayLevelEmphasis"  3.000000
#     4.  "LargeDependenceLowGrayLevelEmphasis"  2.000000
#
# Variable Importance: NUM_NODES:
#     1.                "HighGrayLevelEmphasis" 241.000000 ################
#     2. "LargeDependenceHighGrayLevelEmphasis" 209.000000 #############
#     3.                    "DependenceEntropy" 181.000000 ###########
#     4. "SmallDependenceHighGrayLevelEmphasis" 115.000000 #######
#     5.  "SmallDependenceLowGrayLevelEmphasis" 101.000000 ######
#     6.               "GrayLevelNonUniformity" 86.000000 #####
#     7.                 "LowGrayLevelEmphasis" 86.000000 #####
#     8.  "LargeDependenceLowGrayLevelEmphasis" 75.000000 ####
#     9.              "SmallDependenceEmphasis" 67.000000 ###
#    10.                   "DependenceVariance" 61.000000 ###
#    11.                    "GrayLevelVariance" 61.000000 ###
#    12.              "LargeDependenceEmphasis" 32.000000 #
#    13.              "DependenceNonUniformity" 19.000000
#    14.    "DependenceNonUniformityNormalized" 11.000000
#
# Variable Importance: SUM_SCORE:
#     1.                "HighGrayLevelEmphasis" 19027.933495 ################
#     2. "LargeDependenceHighGrayLevelEmphasis" 4728.540480 ###
#     3.                    "DependenceEntropy" 1491.000713 #
#     4.                 "LowGrayLevelEmphasis" 694.815216
#     5. "SmallDependenceHighGrayLevelEmphasis" 669.511235
#     6.  "SmallDependenceLowGrayLevelEmphasis" 566.498225
#     7.  "LargeDependenceLowGrayLevelEmphasis" 411.626604
#     8.               "GrayLevelNonUniformity" 361.632056
#     9.              "SmallDependenceEmphasis" 355.253726
#    10.                   "DependenceVariance" 214.138709
#    11.                    "GrayLevelVariance" 198.551585
#    12.              "LargeDependenceEmphasis" 89.662028
#    13.              "DependenceNonUniformity" 64.240154
#    14.    "DependenceNonUniformityNormalized" 46.711387
#
#
#
# Loss: BINOMIAL_LOG_LIKELIHOOD
# Validation loss value: 0.492674
# Number of trees per iteration: 1
# Node format: NOT_SET
# Number of trees: 50
# Total number of nodes: 2740
#
# Number of nodes by tree:
# Count: 50 Average: 54.8 StdDev: 7.12461
# Min: 37 Max: 63 Ignored: 0
# ----------------------------------------------
# [ 37, 38) 1   2.00%   2.00% #
# [ 38, 39) 0   0.00%   2.00%
# [ 39, 41) 0   0.00%   2.00%
# [ 41, 42) 0   0.00%   2.00%
# [ 42, 43) 0   0.00%   2.00%
# [ 43, 45) 5  10.00%  12.00% ######
# [ 45, 46) 4   8.00%  20.00% ####
# [ 46, 47) 0   0.00%  20.00%
# [ 47, 49) 3   6.00%  26.00% ###
# [ 49, 50) 1   2.00%  28.00% #
# [ 50, 51) 0   0.00%  28.00%
# [ 51, 53) 1   2.00%  30.00% #
# [ 53, 54) 1   2.00%  32.00% #
# [ 54, 55) 0   0.00%  32.00%
# [ 55, 57) 5  10.00%  42.00% ######
# [ 57, 58) 7  14.00%  56.00% ########
# [ 58, 59) 0   0.00%  56.00%
# [ 59, 61) 7  14.00%  70.00% ########
# [ 61, 62) 9  18.00%  88.00% ##########
# [ 62, 63] 6  12.00% 100.00% #######
#
# Depth by leafs:
# Count: 1395 Average: 4.89534 StdDev: 0.403142
# Min: 2 Max: 5 Ignored: 0
# ----------------------------------------------
# [ 2, 3)   11   0.79%   0.79%
# [ 3, 4)   15   1.08%   1.86%
# [ 4, 5)   83   5.95%   7.81% #
# [ 5, 5] 1286  92.19% 100.00% ##########
#
# Number of training obs by leaf:
# Count: 1395 Average: 955.52 StdDev: 2426.89
# Min: 5 Max: 20091 Ignored: 0
# ----------------------------------------------
# [     5,  1009) 1168  83.73%  83.73% ##########
# [  1009,  2013)   73   5.23%  88.96% #
# [  2013,  3018)   21   1.51%  90.47%
# [  3018,  4022)   42   3.01%  93.48%
# [  4022,  5026)   12   0.86%  94.34%
# [  5026,  6031)   11   0.79%  95.13%
# [  6031,  7035)   13   0.93%  96.06%
# [  7035,  8039)   13   0.93%  96.99%
# [  8039,  9044)    3   0.22%  97.20%
# [  9044, 10048)    5   0.36%  97.56%
# [ 10048, 11052)    5   0.36%  97.92%
# [ 11052, 12057)    5   0.36%  98.28%
# [ 12057, 13061)   10   0.72%  99.00%
# [ 13061, 14065)    6   0.43%  99.43%
# [ 14065, 15070)    5   0.36%  99.78%
# [ 15070, 16074)    0   0.00%  99.78%
# [ 16074, 17078)    0   0.00%  99.78%
# [ 17078, 18083)    2   0.14%  99.93%
# [ 18083, 19087)    0   0.00%  99.93%
# [ 19087, 20091]    1   0.07% 100.00%
#
# Attribute in nodes:
# 	241 : HighGrayLevelEmphasis [NUMERICAL]
# 	209 : LargeDependenceHighGrayLevelEmphasis [NUMERICAL]
# 	181 : DependenceEntropy [NUMERICAL]
# 	115 : SmallDependenceHighGrayLevelEmphasis [NUMERICAL]
# 	101 : SmallDependenceLowGrayLevelEmphasis [NUMERICAL]
# 	86 : LowGrayLevelEmphasis [NUMERICAL]
# 	86 : GrayLevelNonUniformity [NUMERICAL]
# 	75 : LargeDependenceLowGrayLevelEmphasis [NUMERICAL]
# 	67 : SmallDependenceEmphasis [NUMERICAL]
# 	61 : GrayLevelVariance [NUMERICAL]
# 	61 : DependenceVariance [NUMERICAL]
# 	32 : LargeDependenceEmphasis [NUMERICAL]
# 	19 : DependenceNonUniformity [NUMERICAL]
# 	11 : DependenceNonUniformityNormalized [NUMERICAL]
#
# Attribute in nodes with depth <= 0:
# 	37 : HighGrayLevelEmphasis [NUMERICAL]
# 	8 : LargeDependenceHighGrayLevelEmphasis [NUMERICAL]
# 	3 : LowGrayLevelEmphasis [NUMERICAL]
# 	2 : LargeDependenceLowGrayLevelEmphasis [NUMERICAL]
#
# Attribute in nodes with depth <= 1:
# 	65 : HighGrayLevelEmphasis [NUMERICAL]
# 	48 : LargeDependenceHighGrayLevelEmphasis [NUMERICAL]
# 	7 : DependenceVariance [NUMERICAL]
# 	6 : LowGrayLevelEmphasis [NUMERICAL]
# 	6 : LargeDependenceLowGrayLevelEmphasis [NUMERICAL]
# 	5 : SmallDependenceLowGrayLevelEmphasis [NUMERICAL]
# 	5 : GrayLevelNonUniformity [NUMERICAL]
# 	4 : DependenceEntropy [NUMERICAL]
# 	2 : SmallDependenceHighGrayLevelEmphasis [NUMERICAL]
# 	2 : GrayLevelVariance [NUMERICAL]
#
# Attribute in nodes with depth <= 2:
# 	104 : HighGrayLevelEmphasis [NUMERICAL]
# 	76 : LargeDependenceHighGrayLevelEmphasis [NUMERICAL]
# 	49 : DependenceEntropy [NUMERICAL]
# 	17 : SmallDependenceLowGrayLevelEmphasis [NUMERICAL]
# 	17 : LowGrayLevelEmphasis [NUMERICAL]
# 	15 : DependenceVariance [NUMERICAL]
# 	14 : LargeDependenceLowGrayLevelEmphasis [NUMERICAL]
# 	14 : GrayLevelNonUniformity [NUMERICAL]
# 	12 : SmallDependenceHighGrayLevelEmphasis [NUMERICAL]
# 	9 : GrayLevelVariance [NUMERICAL]
# 	6 : SmallDependenceEmphasis [NUMERICAL]
# 	5 : LargeDependenceEmphasis [NUMERICAL]
# 	1 : DependenceNonUniformity [NUMERICAL]
#
# Attribute in nodes with depth <= 3:
# 	144 : HighGrayLevelEmphasis [NUMERICAL]
# 	133 : LargeDependenceHighGrayLevelEmphasis [NUMERICAL]
# 	97 : DependenceEntropy [NUMERICAL]
# 	62 : SmallDependenceLowGrayLevelEmphasis [NUMERICAL]
# 	45 : SmallDependenceHighGrayLevelEmphasis [NUMERICAL]
# 	43 : LowGrayLevelEmphasis [NUMERICAL]
# 	36 : SmallDependenceEmphasis [NUMERICAL]
# 	34 : LargeDependenceLowGrayLevelEmphasis [NUMERICAL]
# 	33 : GrayLevelNonUniformity [NUMERICAL]
# 	30 : DependenceVariance [NUMERICAL]
# 	21 : GrayLevelVariance [NUMERICAL]
# 	15 : LargeDependenceEmphasis [NUMERICAL]
# 	7 : DependenceNonUniformity [NUMERICAL]
# 	2 : DependenceNonUniformityNormalized [NUMERICAL]
#
# Attribute in nodes with depth <= 5:
# 	241 : HighGrayLevelEmphasis [NUMERICAL]
# 	209 : LargeDependenceHighGrayLevelEmphasis [NUMERICAL]
# 	181 : DependenceEntropy [NUMERICAL]
# 	115 : SmallDependenceHighGrayLevelEmphasis [NUMERICAL]
# 	101 : SmallDependenceLowGrayLevelEmphasis [NUMERICAL]
# 	86 : LowGrayLevelEmphasis [NUMERICAL]
# 	86 : GrayLevelNonUniformity [NUMERICAL]
# 	75 : LargeDependenceLowGrayLevelEmphasis [NUMERICAL]
# 	67 : SmallDependenceEmphasis [NUMERICAL]
# 	61 : GrayLevelVariance [NUMERICAL]
# 	61 : DependenceVariance [NUMERICAL]
# 	32 : LargeDependenceEmphasis [NUMERICAL]
# 	19 : DependenceNonUniformity [NUMERICAL]
# 	11 : DependenceNonUniformityNormalized [NUMERICAL]
#
# Condition type in nodes:
# 	1345 : HigherCondition
# Condition type in nodes with depth <= 0:
# 	50 : HigherCondition
# Condition type in nodes with depth <= 1:
# 	150 : HigherCondition
# Condition type in nodes with depth <= 2:
# 	339 : HigherCondition
# Condition type in nodes with depth <= 3:
# 	702 : HigherCondition
# Condition type in nodes with depth <= 5:
# 	1345 : HigherCondition
#
# Training logs:
# Number of iteration to final model: 50
# 	Iter:1 train-loss:1.258695 valid-loss:1.264846  train-accuracy:0.896282 valid-accuracy:0.887899
# 	Iter:2 train-loss:1.150775 valid-loss:1.163865  train-accuracy:0.898396 valid-accuracy:0.883039
# 	Iter:3 train-loss:1.063671 valid-loss:1.082618  train-accuracy:0.898952 valid-accuracy:0.882581
# 	Iter:4 train-loss:0.987428 valid-loss:1.014341  train-accuracy:0.900739 valid-accuracy:0.875011
# 	Iter:5 train-loss:0.922249 valid-loss:0.953636  train-accuracy:0.900680 valid-accuracy:0.876274
# 	Iter:6 train-loss:0.866138 valid-loss:0.903114  train-accuracy:0.902442 valid-accuracy:0.879337
# 	Iter:16 train-loss:0.552615 valid-loss:0.622787  train-accuracy:0.910286 valid-accuracy:0.881235
# 	Iter:26 train-loss:0.439341 valid-loss:0.535871  train-accuracy:0.927498 valid-accuracy:0.893132
# 	Iter:36 train-loss:0.386934 valid-loss:0.505274  train-accuracy:0.931800 valid-accuracy:0.900707
# 	Iter:46 train-loss:0.350700 valid-loss:0.494932  train-accuracy:0.937105 valid-accuracy:0.901610
# 	Iter:56 train-loss:0.329843 valid-loss:0.496657  train-accuracy:0.940665 valid-accuracy:0.899898
# 	Iter:66 train-loss:0.309627 valid-loss:0.497175  train-accuracy:0.944345 valid-accuracy:0.900800
# 	Iter:76 train-loss:0.292645 valid-loss:0.497441  train-accuracy:0.947534 valid-accuracy:0.893678

# %%
# Model features
model.make_inspector().features()
# Out:
# ["DependenceEntropy" (1; #0),
#  "DependenceNonUniformity" (1; #1),
#  "DependenceNonUniformityNormalized" (1; #2),
#  "DependenceVariance" (1; #3),
#  "GrayLevelNonUniformity" (1; #4),
#  "GrayLevelVariance" (1; #5),
#  "HighGrayLevelEmphasis" (1; #6),
#  "LargeDependenceEmphasis" (1; #7),
#  "LargeDependenceHighGrayLevelEmphasis" (1; #8),
#  "LargeDependenceLowGrayLevelEmphasis" (1; #9),
#  "LowGrayLevelEmphasis" (1; #10),
#  "SmallDependenceEmphasis" (1; #11),
#  "SmallDependenceHighGrayLevelEmphasis" (1; #12),
#  "SmallDependenceLowGrayLevelEmphasis" (1; #13)]

# %%
# Feature importance
model.make_inspector().variable_importances()
# Out:
# {'INV_MEAN_MIN_DEPTH': [("HighGrayLevelEmphasis" (1; #6), 0.49898725078105205),
#   ("LargeDependenceHighGrayLevelEmphasis" (1; #8), 0.3132008381615202),
#   ("DependenceEntropy" (1; #0), 0.2135367060102044),
#   ("LowGrayLevelEmphasis" (1; #10), 0.19307306700358062),
#   ("SmallDependenceLowGrayLevelEmphasis" (1; #13), 0.18942946614302633),
#   ("SmallDependenceHighGrayLevelEmphasis" (1; #12), 0.18625922964040947),
#   ("LargeDependenceLowGrayLevelEmphasis" (1; #9), 0.18615463861687417),
#   ("GrayLevelNonUniformity" (1; #4), 0.18574954694134574),
#   ("DependenceVariance" (1; #3), 0.1842152247825109),
#   ("SmallDependenceEmphasis" (1; #11), 0.17905051737821556),
#   ("GrayLevelVariance" (1; #5), 0.17748596709746),
#   ("LargeDependenceEmphasis" (1; #7), 0.17442905151345614),
#   ("DependenceNonUniformity" (1; #1), 0.1718054089983792),
#   ("DependenceNonUniformityNormalized" (1; #2), 0.1706966118072635)],
#  'SUM_SCORE': [("HighGrayLevelEmphasis" (1; #6), 19027.93349475394),
#   ("LargeDependenceHighGrayLevelEmphasis" (1; #8), 4728.540480336845),
#   ("DependenceEntropy" (1; #0), 1491.000712988619),
#   ("LowGrayLevelEmphasis" (1; #10), 694.8152163940525),
#   ("SmallDependenceHighGrayLevelEmphasis" (1; #12), 669.5112352492233),
#   ("SmallDependenceLowGrayLevelEmphasis" (1; #13), 566.4982249778212),
#   ("LargeDependenceLowGrayLevelEmphasis" (1; #9), 411.62660363332634),
#   ("GrayLevelNonUniformity" (1; #4), 361.6320558407151),
#   ("SmallDependenceEmphasis" (1; #11), 355.2537258761824),
#   ("DependenceVariance" (1; #3), 214.13870873279433),
#   ("GrayLevelVariance" (1; #5), 198.55158520965622),
#   ("LargeDependenceEmphasis" (1; #7), 89.66202819990365),
#   ("DependenceNonUniformity" (1; #1), 64.24015431930297),
#   ("DependenceNonUniformityNormalized" (1; #2), 46.711386886240255)],
#  'NUM_AS_ROOT': [("HighGrayLevelEmphasis" (1; #6), 37.0),
#   ("LargeDependenceHighGrayLevelEmphasis" (1; #8), 8.0),
#   ("LowGrayLevelEmphasis" (1; #10), 3.0),
#   ("LargeDependenceLowGrayLevelEmphasis" (1; #9), 2.0)],
#  'NUM_NODES': [("HighGrayLevelEmphasis" (1; #6), 241.0),
#   ("LargeDependenceHighGrayLevelEmphasis" (1; #8), 209.0),
#   ("DependenceEntropy" (1; #0), 181.0),
#   ("SmallDependenceHighGrayLevelEmphasis" (1; #12), 115.0),
#   ("SmallDependenceLowGrayLevelEmphasis" (1; #13), 101.0),
#   ("GrayLevelNonUniformity" (1; #4), 86.0),
#   ("LowGrayLevelEmphasis" (1; #10), 86.0),
#   ("LargeDependenceLowGrayLevelEmphasis" (1; #9), 75.0),
#   ("SmallDependenceEmphasis" (1; #11), 67.0),
#   ("DependenceVariance" (1; #3), 61.0),
#   ("GrayLevelVariance" (1; #5), 61.0),
#   ("LargeDependenceEmphasis" (1; #7), 32.0),
#   ("DependenceNonUniformity" (1; #1), 19.0),
#   ("DependenceNonUniformityNormalized" (1; #2), 11.0)]}

# %%
# Model self evaluation
model.make_inspector().evaluation()
# Out:
# Evaluation(num_examples=None, accuracy=0.8993561863899231, loss=0.4926742613315582, rmse=None, ndcg=None, aucs=None, auuc=None, qini=None)

# %%
logs = model.make_inspector().training_logs()

plt.figure(figsize=(12, 4))
plt.subplot(1, 2, 1)
plt.plot([log.num_trees for log in logs], [log.evaluation.accuracy for log in logs])
plt.xlabel("Number of trees")
plt.ylabel("Accuracy (out-of-bag)")
plt.subplot(1, 2, 2)
plt.plot([log.num_trees for log in logs], [log.evaluation.loss for log in logs])
plt.xlabel("Number of trees")
plt.ylabel("Logloss (out-of-bag)")
plt.show()

# %% [markdown]
# Calculate the score of our hold-out validation dataset

# %%
predictions = model.predict(val_ds)
y_true      = validation_data["label"]

from sklearn.metrics import roc_auc_score
ROC_AUC = roc_auc_score(y_true, predictions)
print("The ROC AUC score is %.5f" % ROC_AUC )
# Out:
# 1/5 [=====>........................] - ETA: 0s
# 5/5 [==============================] - 0s 3ms/step
# The ROC AUC score is 0.99586

# %%
# Compute binary classification metrics with sklearn
import numpy as np
from sklearn.metrics import (
    accuracy_score,
    precision_score,
    recall_score,
    f1_score,
    roc_auc_score,
    average_precision_score,
    confusion_matrix,
    classification_report,
    matthews_corrcoef,
    log_loss,
    brier_score_loss,
)

# Get predictions (probabilities or class labels)
preds = model.predict(test_ds)
# If model outputs probabilities, convert to labels by threshold 0.5
if preds.ndim == 2:
    # For TFDF classification, preds may be class probabilities with shape (N, 2)
    if preds.shape[1] == 2:
        pos_probs = preds[:, 1]
    else:
        # If single-probability column (positive class)
        pos_probs = preds[:, -1]
    y_pred = (pos_probs >= 0.5).astype(int)
else:
    # Already class labels
    y_pred = preds.astype(int)
    pos_probs = None

# Ground truth labels (must be 0/1 integers)
y_true = test_data["label"].astype(int).to_numpy()

# Core metrics
metrics = {}
metrics["accuracy"] = accuracy_score(y_true, y_pred)
metrics["precision"] = precision_score(y_true, y_pred, zero_division=0)
metrics["recall"] = recall_score(y_true, y_pred, zero_division=0)
metrics["f1"] = f1_score(y_true, y_pred, zero_division=0)
metrics["mcc"] = matthews_corrcoef(y_true, y_pred)

# Probabilistic metrics (only if we have probabilities)
if pos_probs is not None:
    metrics["roc_auc"] = roc_auc_score(y_true, pos_probs)
    metrics["pr_auc"] = average_precision_score(y_true, pos_probs)
    metrics["log_loss"] = log_loss(y_true, pos_probs, labels=[0,1])
    metrics["brier_score"] = brier_score_loss(y_true, pos_probs)

# Confusion matrix and detailed report
cm = confusion_matrix(y_true, y_pred, labels=[0,1])
report = classification_report(y_true, y_pred, digits=4)

print("Sklearn binary metrics:")
for k, v in metrics.items():
    print(f"{k}: {v:.4f}")
print("\nConfusion matrix:\n", cm)
print("\nClassification report:\n", report)
# Out:
# 1/9 [==>...........................] - ETA: 0s
# 9/9 [==============================] - 0s 4ms/step
# Sklearn binary metrics:
# accuracy: 0.9632
# precision: 0.7951
# recall: 0.8482
# f1: 0.8208
# mcc: 0.8009
# roc_auc: 0.9596
# pr_auc: 0.8825
# log_loss: 0.1374
# brier_score: 0.0317
#
# Confusion matrix:
#  [[7818  193]
#  [ 134  749]]
#
# Classification report:
#                precision    recall  f1-score   support
#
#            0     0.9831    0.9759    0.9795      8011
#            1     0.7951    0.8482    0.8208       883
#
#     accuracy                         0.9632      8894
#    macro avg     0.8891    0.9121    0.9002      8894
# weighted avg     0.9645    0.9632    0.9638      8894
