# %%
# Import packages and modules
import numpy  as np
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow_decision_forests as tfdf

from sklearn.model_selection import train_test_split
# Out:
# 2026-09-11 03:35:49.616233: I tensorflow/core/util/port.cc:113] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2026-09-11 03:35:49.981886: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2026-09-11 03:35:54.300884: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
# Check the version of TensorFlow Decision Forests
print("Found TensorFlow Decision Forests v" + tfdf.__version__)
# Out:
# Found TensorFlow Decision Forests v1.9.1

# %%
datasetPath = "dataset/10p/all/kernel3/"

# %%
# Parameters
datasetPath = "dataset/10p/all/kernel3/"

# %%
# train/validation/test = 70/10/20
train_data = pd.read_csv(f"{datasetPath}dataset.train.csv")
validation_data = pd.read_csv(f"{datasetPath}dataset.validation.csv")
test_data = pd.read_csv(f"{datasetPath}dataset.test.csv")

# %%
from sklearn.utils.class_weight import compute_class_weight

# tinh class weight tren tap train
classes = np.array([0, 1])
weights = compute_class_weight(class_weight="balanced", classes=classes, y=train_data["label"])
class_weight = {0: weights[0], 1: weights[1]}

# gan sample_weight cho tung dong
train_data["sample_weight"] = train_data["label"].map(class_weight)
validation_data["sample_weight"] = validation_data["label"].map(class_weight)
test_data["sample_weight"] = test_data["label"].map(class_weight)

# Convert the dataset into a TensorFlow dataset.
train_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    train_data, label="label", weight="sample_weight"
)         
val_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    validation_data, label="label", weight="sample_weight"
)
test_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    test_data, label="label", weight="sample_weight"
)
# Out:
# 2026-09-11 03:36:07.723778: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:984] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2026-09-11 03:36:07.724881: W tensorflow/core/common_runtime/gpu/gpu_device.cc:2251] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...

# %%
import keras

# %%
# %%time

# Train a Random Forest model.
model = tfdf.keras.RandomForestModel()

# Add evaluation metrics
model.compile(
    metrics=["accuracy"]
)
model.fit(x=train_ds)

# # Train a Gradient Boosted Trees model.
# model = tfdf.keras.GradientBoostedTreesModel(num_trees=1500)
# model.fit(train_ds)
# Out:
# Use /tmp/tmpep1jzmrr as temporary training directory
# Reading training dataset...
# Training dataset read in 0:00:04.138910. Found 29597 examples.
# Training model...
# [INFO 26-09-11 03:36:17.0839 UTC kernel.cc:1233] Loading model from path /tmp/tmpep1jzmrr/model/ with prefix 4c70bb2c49bb4261
# Model trained in 0:00:03.749617
# Compiling model...
# [INFO 26-09-11 03:36:17.3099 UTC decision_forest.cc:734] Model loaded with 300 root(s), 193698 node(s), and 93 input feature(s).
# [INFO 26-09-11 03:36:17.3100 UTC abstract_model.cc:1362] Engine "RandomForestOptPred" built
# [INFO 26-09-11 03:36:17.3100 UTC kernel.cc:1061] Use fast generic engine
# Model compiled.
# CPU times: user 46.9 s, sys: 747 ms, total: 47.7 s
# Wall time: 11.9 s

# %%
# Evaluate the model
evaluate = model.evaluate(val_ds, return_dict=True)
print()

for name, value in evaluate.items():
    print(f"{name}: {value:.4f}")
# Out:
# WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 1/5 [=====>........................] - ETA: 12s - loss: 0.0000e+00 - accuracy: 0.9950
# 4/5 [=======================>......] - ETA: 0s - loss: 0.0000e+00 - accuracy: 0.9955
# 5/5 [==============================] - 3s 19ms/step - loss: 0.0000e+00 - accuracy: 0.9952
# loss: 0.0000
# accuracy: 0.9952

# %%
# Model Summary
model.summary()
# Out:
# Model: "random_forest_model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
# =================================================================
# Total params: 1 (1.00 Byte)
# Trainable params: 0 (0.00 Byte)
# Non-trainable params: 1 (1.00 Byte)
# _________________________________________________________________
# Type: "RANDOM_FOREST"
# Task: CLASSIFICATION
# Label: "__LABEL"
#
# Input Features (93):
# 	10Percentile
# 	90Percentile
# 	Autocorrelation
# 	Busyness
# 	ClusterProminence
# 	ClusterShade
# 	ClusterTendency
# 	Coarseness
# 	Complexity
# 	Contrast
# 	Contrast.1
# 	Correlation
# 	DependenceEntropy
# 	DependenceNonUniformity
# 	DependenceNonUniformityNormalized
# 	DependenceVariance
# 	DifferenceAverage
# 	DifferenceEntropy
# 	DifferenceVariance
# 	Energy
# 	Entropy
# 	GrayLevelNonUniformity
# 	GrayLevelNonUniformity.1
# 	GrayLevelNonUniformity.2
# 	GrayLevelNonUniformityNormalized
# 	GrayLevelNonUniformityNormalized.1
# 	GrayLevelVariance
# 	GrayLevelVariance.1
# 	GrayLevelVariance.2
# 	HighGrayLevelEmphasis
# 	HighGrayLevelRunEmphasis
# 	HighGrayLevelZoneEmphasis
# 	Id
# 	Idm
# 	Idmn
# 	Idn
# 	Imc1
# 	Imc2
# 	InterquartileRange
# 	InverseVariance
# 	JointAverage
# 	JointEnergy
# 	JointEntropy
# 	Kurtosis
# 	LargeAreaEmphasis
# 	LargeAreaHighGrayLevelEmphasis
# 	LargeAreaLowGrayLevelEmphasis
# 	LargeDependenceEmphasis
# 	LargeDependenceHighGrayLevelEmphasis
# 	LargeDependenceLowGrayLevelEmphasis
# 	LongRunEmphasis
# 	LongRunHighGrayLevelEmphasis
# 	LongRunLowGrayLevelEmphasis
# 	LowGrayLevelEmphasis
# 	LowGrayLevelRunEmphasis
# 	LowGrayLevelZoneEmphasis
# 	MCC
# 	Maximum
# 	MaximumProbability
# 	Mean
# 	MeanAbsoluteDeviation
# 	Median
# 	Minimum
# 	Range
# 	RobustMeanAbsoluteDeviation
# 	RootMeanSquared
# 	RunEntropy
# 	RunLengthNonUniformity
# 	RunLengthNonUniformityNormalized
# 	RunPercentage
# 	RunVariance
# 	ShortRunEmphasis
# 	ShortRunHighGrayLevelEmphasis
# 	ShortRunLowGrayLevelEmphasis
# 	SizeZoneNonUniformity
# 	SizeZoneNonUniformityNormalized
# 	Skewness
# 	SmallAreaEmphasis
# 	SmallAreaHighGrayLevelEmphasis
# 	SmallAreaLowGrayLevelEmphasis
# 	SmallDependenceEmphasis
# 	SmallDependenceHighGrayLevelEmphasis
# 	SmallDependenceLowGrayLevelEmphasis
# 	Strength
# 	SumAverage
# 	SumEntropy
# 	SumSquares
# 	TotalEnergy
# 	Uniformity
# 	Variance
# 	ZoneEntropy
# 	ZonePercentage
# 	ZoneVariance
#
# Trained with weights
#
# Variable Importance: INV_MEAN_MIN_DEPTH:
#     1.         "LongRunHighGrayLevelEmphasis"  0.123371 ################
#     2.             "GrayLevelNonUniformity.2"  0.105871 ########
#     3. "LargeDependenceHighGrayLevelEmphasis"  0.103280 #######
#     4.                           "Coarseness"  0.102331 ######
#     5.                         "90Percentile"  0.101255 ######
#     6.                               "Median"  0.100904 ######
#     7.            "HighGrayLevelZoneEmphasis"  0.100116 #####
#     8.                                  "Idn"  0.099394 #####
#     9.                             "Busyness"  0.099240 #####
#    10.                              "Maximum"  0.099027 #####
#    11.                                 "Mean"  0.098980 #####
#    12.                          "TotalEnergy"  0.098410 ####
#    13.                      "Autocorrelation"  0.097932 ####
#    14.                                 "Idmn"  0.097825 ####
#    15.                "HighGrayLevelEmphasis"  0.097808 ####
#    16.                      "RootMeanSquared"  0.097369 ####
#    17.                               "Energy"  0.097201 ####
#    18.                         "JointAverage"  0.096998 ####
#    19.                           "SumAverage"  0.096118 ###
#    20.       "LargeAreaHighGrayLevelEmphasis"  0.095904 ###
#    21.  "SmallDependenceLowGrayLevelEmphasis"  0.095237 ###
#    22.             "HighGrayLevelRunEmphasis"  0.094525 ###
#    23.                             "Skewness"  0.094411 ###
#    24.         "ShortRunLowGrayLevelEmphasis"  0.094341 ###
#    25.        "ShortRunHighGrayLevelEmphasis"  0.093700 ##
#    26.                 "LowGrayLevelEmphasis"  0.093143 ##
#    27.             "LowGrayLevelZoneEmphasis"  0.093011 ##
#    28.                          "Correlation"  0.092697 ##
#    29.       "SmallAreaHighGrayLevelEmphasis"  0.092286 ##
#    30.          "LongRunLowGrayLevelEmphasis"  0.092189 ##
#    31.                      "InverseVariance"  0.091945 ##
#    32.                         "ClusterShade"  0.091885 ##
#    33.        "SmallAreaLowGrayLevelEmphasis"  0.091501 #
#    34.  "LargeDependenceLowGrayLevelEmphasis"  0.091487 #
#    35.                         "10Percentile"  0.091351 #
#    36.                    "DependenceEntropy"  0.091229 #
#    37.              "LowGrayLevelRunEmphasis"  0.091033 #
#    38.                                  "MCC"  0.090806 #
#    39.              "SmallDependenceEmphasis"  0.090315 #
#    40.    "DependenceNonUniformityNormalized"  0.090273 #
#    41.                                 "Imc1"  0.090185 #
#    42.              "LargeDependenceEmphasis"  0.090155 #
#    43. "SmallDependenceHighGrayLevelEmphasis"  0.090017 #
#    44.                      "LongRunEmphasis"  0.089975 #
#    45.                              "Minimum"  0.089916 #
#    46.                    "DifferenceEntropy"  0.089903 #
#    47.                          "RunVariance"  0.089637 #
#    48.                   "DifferenceVariance"  0.089622 #
#    49.                             "Strength"  0.089613 #
#    50.                       "ZonePercentage"  0.089537 #
#    51.                                  "Idm"  0.089522 #
#    52.                        "RunPercentage"  0.089446 #
#    53.                           "Contrast.1"  0.089419 #
#    54.                                   "Id"  0.089298
#    55.              "DependenceNonUniformity"  0.089154
#    56.                                 "Imc2"  0.089127
#    57.     "RunLengthNonUniformityNormalized"  0.089078
#    58.        "LargeAreaLowGrayLevelEmphasis"  0.089003
#    59.                             "Kurtosis"  0.088983
#    60.                     "ShortRunEmphasis"  0.088781
#    61.               "RunLengthNonUniformity"  0.088759
#    62.                    "DifferenceAverage"  0.088722
#    63.                             "Contrast"  0.088705
#    64.                                "Range"  0.088655
#    65.                           "SumEntropy"  0.088626
#    66.                "SizeZoneNonUniformity"  0.088558
#    67.                   "DependenceVariance"  0.088554
#    68.             "GrayLevelNonUniformity.1"  0.088335
#    69.                           "Complexity"  0.088201
#    70.               "GrayLevelNonUniformity"  0.088184
#    71.                           "RunEntropy"  0.088164
#    72.                          "ZoneEntropy"  0.088079
#    73.                  "GrayLevelVariance.2"  0.087936
#    74.                   "InterquartileRange"  0.087936
#    75.                    "SmallAreaEmphasis"  0.087885
#    76.                           "Uniformity"  0.087879
#    77.                   "MaximumProbability"  0.087819
#    78.                    "LargeAreaEmphasis"  0.087750
#    79.     "GrayLevelNonUniformityNormalized"  0.087735
#    80.          "RobustMeanAbsoluteDeviation"  0.087733
#    81.   "GrayLevelNonUniformityNormalized.1"  0.087702
#    82.                              "Entropy"  0.087693
#    83.      "SizeZoneNonUniformityNormalized"  0.087661
#    84.                      "ClusterTendency"  0.087642
#    85.                    "ClusterProminence"  0.087548
#    86.                         "ZoneVariance"  0.087516
#    87.                  "GrayLevelVariance.1"  0.087504
#    88.                             "Variance"  0.087467
#    89.                          "JointEnergy"  0.087427
#    90.                         "JointEntropy"  0.087382
#    91.                "MeanAbsoluteDeviation"  0.087258
#    92.                    "GrayLevelVariance"  0.087158
#    93.                           "SumSquares"  0.087127
#
# Variable Importance: NUM_AS_ROOT:
#     1.         "LongRunHighGrayLevelEmphasis" 43.000000 ################
#     2.            "HighGrayLevelZoneEmphasis" 27.000000 #########
#     3.                         "90Percentile" 23.000000 ########
#     4.                                 "Mean" 20.000000 #######
#     5.                          "TotalEnergy" 20.000000 #######
#     6.                               "Energy" 18.000000 ######
#     7.                "HighGrayLevelEmphasis" 17.000000 ######
#     8.             "HighGrayLevelRunEmphasis" 15.000000 #####
#     9.                      "RootMeanSquared" 15.000000 #####
#    10.                      "Autocorrelation" 12.000000 ####
#    11.                         "JointAverage" 10.000000 ###
#    12.             "LowGrayLevelZoneEmphasis" 10.000000 ###
#    13.        "ShortRunHighGrayLevelEmphasis" 10.000000 ###
#    14.                           "SumAverage"  9.000000 ###
#    15.                               "Median"  8.000000 ##
#    16.       "SmallAreaHighGrayLevelEmphasis"  8.000000 ##
#    17.                              "Maximum"  7.000000 ##
#    18.                 "LowGrayLevelEmphasis"  5.000000 #
#    19.         "ShortRunLowGrayLevelEmphasis"  5.000000 #
#    20.          "LongRunLowGrayLevelEmphasis"  3.000000
#    21.        "SmallAreaLowGrayLevelEmphasis"  3.000000
#    22.                         "10Percentile"  2.000000
#    23. "LargeDependenceHighGrayLevelEmphasis"  2.000000
#    24.  "SmallDependenceLowGrayLevelEmphasis"  2.000000
#    25.                             "Busyness"  1.000000
#    26.        "LargeAreaLowGrayLevelEmphasis"  1.000000
#    27.  "LargeDependenceLowGrayLevelEmphasis"  1.000000
#    28.              "LowGrayLevelRunEmphasis"  1.000000
#    29.                                  "MCC"  1.000000
#    30.                          "ZoneEntropy"  1.000000
#
# Variable Importance: NUM_NODES:
#     1.                                  "Idn" 4344.000000 ################
#     2.                                 "Idmn" 3775.000000 #############
#     3.                             "Skewness" 1939.000000 #####
#     4.                           "Coarseness" 1847.000000 #####
#     5.                              "Maximum" 1846.000000 #####
#     6.             "GrayLevelNonUniformity.2" 1809.000000 #####
#     7.                         "ClusterShade" 1652.000000 ####
#     8.                             "Busyness" 1636.000000 ####
#     9.                          "Correlation" 1521.000000 ####
#    10.                               "Median" 1469.000000 ###
#    11. "LargeDependenceHighGrayLevelEmphasis" 1441.000000 ###
#    12.         "LongRunHighGrayLevelEmphasis" 1428.000000 ###
#    13.                                  "MCC" 1334.000000 ###
#    14.                           "Contrast.1" 1326.000000 ###
#    15.                             "Kurtosis" 1297.000000 ###
#    16.                   "DifferenceVariance" 1231.000000 ##
#    17.                         "90Percentile" 1163.000000 ##
#    18.                    "DifferenceEntropy" 1156.000000 ##
#    19.                                "Range" 1136.000000 ##
#    20.                             "Contrast" 1132.000000 ##
#    21.                    "DependenceEntropy" 1131.000000 ##
#    22.  "SmallDependenceLowGrayLevelEmphasis" 1126.000000 ##
#    23.       "SmallAreaHighGrayLevelEmphasis" 1116.000000 ##
#    24.        "SmallAreaLowGrayLevelEmphasis" 1111.000000 ##
#    25.       "LargeAreaHighGrayLevelEmphasis" 1087.000000 ##
#    26.            "HighGrayLevelZoneEmphasis" 1072.000000 ##
#    27.                                 "Imc1" 1062.000000 ##
#    28.                      "InverseVariance" 1058.000000 ##
#    29.                    "DifferenceAverage" 1050.000000 #
#    30.                             "Strength" 1048.000000 #
#    31.             "LowGrayLevelZoneEmphasis" 1042.000000 #
#    32.                              "Minimum" 1012.000000 #
#    33. "SmallDependenceHighGrayLevelEmphasis" 1012.000000 #
#    34.                         "10Percentile" 992.000000 #
#    35.                      "Autocorrelation" 960.000000 #
#    36.          "RobustMeanAbsoluteDeviation" 953.000000 #
#    37.                          "ZoneEntropy" 953.000000 #
#    38.                           "Complexity" 949.000000 #
#    39.              "SmallDependenceEmphasis" 945.000000 #
#    40.                           "SumAverage" 940.000000 #
#    41.                "SizeZoneNonUniformity" 919.000000 #
#    42.      "SizeZoneNonUniformityNormalized" 913.000000 #
#    43.                                 "Imc2" 912.000000 #
#    44.                    "SmallAreaEmphasis" 910.000000 #
#    45.                  "GrayLevelVariance.2" 907.000000 #
#    46.                         "JointAverage" 902.000000 #
#    47.                                 "Mean" 902.000000 #
#    48.                   "DependenceVariance" 897.000000 #
#    49.                   "InterquartileRange" 891.000000 #
#    50.                           "SumEntropy" 880.000000 #
#    51.  "LargeDependenceLowGrayLevelEmphasis" 879.000000 #
#    52.                                   "Id" 871.000000 #
#    53.                 "LowGrayLevelEmphasis" 870.000000 #
#    54.         "ShortRunLowGrayLevelEmphasis" 870.000000 #
#    55.          "LongRunLowGrayLevelEmphasis" 863.000000 #
#    56.                          "TotalEnergy" 862.000000 #
#    57.              "LargeDependenceEmphasis" 845.000000 #
#    58.        "LargeAreaLowGrayLevelEmphasis" 838.000000 #
#    59.                      "RootMeanSquared" 838.000000 #
#    60.                          "RunVariance" 833.000000 #
#    61.                               "Energy" 830.000000 #
#    62.                      "LongRunEmphasis" 825.000000 #
#    63.                   "MaximumProbability" 824.000000 #
#    64.              "LowGrayLevelRunEmphasis" 812.000000
#    65.                                  "Idm" 805.000000
#    66.                "HighGrayLevelEmphasis" 801.000000
#    67.        "ShortRunHighGrayLevelEmphasis" 791.000000
#    68.                           "RunEntropy" 788.000000
#    69.                      "ClusterTendency" 779.000000
#    70.               "GrayLevelNonUniformity" 770.000000
#    71.             "HighGrayLevelRunEmphasis" 770.000000
#    72.   "GrayLevelNonUniformityNormalized.1" 769.000000
#    73.                    "ClusterProminence" 765.000000
#    74.                           "Uniformity" 757.000000
#    75.              "DependenceNonUniformity" 745.000000
#    76.                       "ZonePercentage" 740.000000
#    77.     "GrayLevelNonUniformityNormalized" 736.000000
#    78.             "GrayLevelNonUniformity.1" 730.000000
#    79.                          "JointEnergy" 716.000000
#    80.    "DependenceNonUniformityNormalized" 714.000000
#    81.                        "RunPercentage" 710.000000
#    82.                              "Entropy" 700.000000
#    83.                         "ZoneVariance" 697.000000
#    84.                    "LargeAreaEmphasis" 677.000000
#    85.     "RunLengthNonUniformityNormalized" 665.000000
#    86.                "MeanAbsoluteDeviation" 662.000000
#    87.               "RunLengthNonUniformity" 660.000000
#    88.                     "ShortRunEmphasis" 658.000000
#    89.                           "SumSquares" 650.000000
#    90.                         "JointEntropy" 639.000000
#    91.                  "GrayLevelVariance.1" 638.000000
#    92.                             "Variance" 593.000000
#    93.                    "GrayLevelVariance" 580.000000
#
# Variable Importance: SUM_SCORE:
#     1.         "LongRunHighGrayLevelEmphasis" 507157.016760 ################
#     2.            "HighGrayLevelZoneEmphasis" 255379.591624 #######
#     3.                         "90Percentile" 243281.799172 #######
#     4.                                 "Mean" 206958.562528 ######
#     5.                          "TotalEnergy" 204950.128147 ######
#     6.                                  "Idn" 194824.334844 #####
#     7.                               "Energy" 182567.305755 #####
#     8.                "HighGrayLevelEmphasis" 178448.967518 #####
#     9.                      "RootMeanSquared" 169410.051018 #####
#    10.                                 "Idmn" 163974.579192 ####
#    11.                      "Autocorrelation" 152170.554759 ####
#    12.             "HighGrayLevelRunEmphasis" 150480.163430 ####
#    13. "LargeDependenceHighGrayLevelEmphasis" 146818.355415 ####
#    14.                               "Median" 138835.468699 ####
#    15.                              "Maximum" 138490.112213 ####
#    16.             "GrayLevelNonUniformity.2" 130944.049342 ###
#    17.                         "JointAverage" 130447.591359 ###
#    18.                           "SumAverage" 123347.125851 ###
#    19.        "ShortRunHighGrayLevelEmphasis" 117175.717284 ###
#    20.                           "Coarseness" 105306.439192 ###
#    21.             "LowGrayLevelZoneEmphasis" 104367.723779 ###
#    22.                             "Busyness" 102277.945719 ##
#    23.       "SmallAreaHighGrayLevelEmphasis" 93086.351289 ##
#    24.         "ShortRunLowGrayLevelEmphasis" 82757.966882 ##
#    25.                 "LowGrayLevelEmphasis" 73429.919351 ##
#    26.  "SmallDependenceLowGrayLevelEmphasis" 72968.007963 ##
#    27.       "LargeAreaHighGrayLevelEmphasis" 71621.620131 #
#    28.                             "Skewness" 55146.552715 #
#    29.        "SmallAreaLowGrayLevelEmphasis" 54583.362168 #
#    30.          "LongRunLowGrayLevelEmphasis" 54347.555886 #
#    31.                          "Correlation" 48193.010679 #
#    32.                         "10Percentile" 46202.197171 #
#    33.                      "InverseVariance" 44103.795373 #
#    34.                    "DependenceEntropy" 42274.888227 #
#    35.                         "ClusterShade" 41103.594781 #
#    36.  "LargeDependenceLowGrayLevelEmphasis" 40349.857999
#    37.              "LowGrayLevelRunEmphasis" 38845.994178
#    38.              "SmallDependenceEmphasis" 35975.836229
#    39.                    "DifferenceEntropy" 34926.984126
#    40.                                  "MCC" 34010.956838
#    41. "SmallDependenceHighGrayLevelEmphasis" 33494.729389
#    42.                           "Contrast.1" 32482.863263
#    43.                                 "Imc1" 31780.353036
#    44.              "LargeDependenceEmphasis" 31572.478445
#    45.                   "DifferenceVariance" 30985.241195
#    46.                      "LongRunEmphasis" 30971.281823
#    47.    "DependenceNonUniformityNormalized" 28576.037278
#    48.                          "RunVariance" 28538.992812
#    49.                             "Strength" 28283.323681
#    50.                    "DifferenceAverage" 27888.183864
#    51.                                  "Idm" 27667.926618
#    52.        "LargeAreaLowGrayLevelEmphasis" 27626.525347
#    53.                              "Minimum" 27367.246383
#    54.                             "Contrast" 27320.553172
#    55.                                   "Id" 27117.501662
#    56.                        "RunPercentage" 26706.557493
#    57.                       "ZonePercentage" 26639.003612
#    58.                                 "Imc2" 25579.934127
#    59.              "DependenceNonUniformity" 25083.894840
#    60.                                "Range" 24048.428191
#    61.     "RunLengthNonUniformityNormalized" 23567.162578
#    62.                "SizeZoneNonUniformity" 22670.838393
#    63.                             "Kurtosis" 22529.357703
#    64.                   "DependenceVariance" 21448.494752
#    65.                           "SumEntropy" 21050.402257
#    66.                     "ShortRunEmphasis" 21022.873502
#    67.               "RunLengthNonUniformity" 20238.984627
#    68.                          "ZoneEntropy" 19571.189210
#    69.                           "Complexity" 18420.162944
#    70.                           "RunEntropy" 18406.337947
#    71.                    "SmallAreaEmphasis" 17560.033714
#    72.               "GrayLevelNonUniformity" 17508.032683
#    73.          "RobustMeanAbsoluteDeviation" 17505.605286
#    74.             "GrayLevelNonUniformity.1" 17273.197634
#    75.      "SizeZoneNonUniformityNormalized" 17154.885122
#    76.                  "GrayLevelVariance.2" 17015.233975
#    77.                   "MaximumProbability" 16604.976281
#    78.                   "InterquartileRange" 16583.621000
#    79.                           "Uniformity" 16254.738265
#    80.                    "LargeAreaEmphasis" 16050.136196
#    81.                              "Entropy" 15388.115808
#    82.                      "ClusterTendency" 15289.289820
#    83.   "GrayLevelNonUniformityNormalized.1" 15188.444728
#    84.     "GrayLevelNonUniformityNormalized" 15158.469612
#    85.                          "JointEnergy" 13576.204280
#    86.                    "ClusterProminence" 13063.830705
#    87.                         "ZoneVariance" 13021.304099
#    88.                  "GrayLevelVariance.1" 12297.313045
#    89.                         "JointEntropy" 12292.540443
#    90.                             "Variance" 12280.906988
#    91.                "MeanAbsoluteDeviation" 11936.432500
#    92.                           "SumSquares" 11291.339752
#    93.                    "GrayLevelVariance" 9981.180197
#
#
#
# Winner takes all: true
# Out-of-bag evaluation: accuracy:0.899274 logloss:0.283194
# Number of trees: 300
# Total number of nodes: 193698
#
# Number of nodes by tree:
# Count: 300 Average: 645.66 StdDev: 32.5212
# Min: 547 Max: 743 Ignored: 0
# ----------------------------------------------
# [ 547, 556)  2   0.67%   0.67% #
# [ 556, 566)  2   0.67%   1.33% #
# [ 566, 576)  0   0.00%   1.33%
# [ 576, 586)  4   1.33%   2.67% #
# [ 586, 596) 14   4.67%   7.33% ####
# [ 596, 606) 15   5.00%  12.33% ####
# [ 606, 615) 16   5.33%  17.67% ####
# [ 615, 625) 21   7.00%  24.67% #####
# [ 625, 635) 28   9.33%  34.00% #######
# [ 635, 645) 39  13.00%  47.00% ##########
# [ 645, 655) 39  13.00%  60.00% ##########
# [ 655, 665) 29   9.67%  69.67% #######
# [ 665, 675) 30  10.00%  79.67% ########
# [ 675, 684) 26   8.67%  88.33% #######
# [ 684, 694) 17   5.67%  94.00% ####
# [ 694, 704)  9   3.00%  97.00% ##
# [ 704, 714)  5   1.67%  98.67% #
# [ 714, 724)  3   1.00%  99.67% #
# [ 724, 734)  0   0.00%  99.67%
# [ 734, 743]  1   0.33% 100.00%
#
# Depth by leafs:
# Count: 96999 Average: 10.5759 StdDev: 2.60061
# Min: 2 Max: 15 Ignored: 0
# ----------------------------------------------
# [  2,  3)     3   0.00%   0.00%
# [  3,  4)   127   0.13%   0.13%
# [  4,  5)   632   0.65%   0.79%
# [  5,  6)  1710   1.76%   2.55% #
# [  6,  7)  3647   3.76%   6.31% ###
# [  7,  8)  6380   6.58%  12.89% #####
# [  8,  9)  9202   9.49%  22.37% #######
# [  9, 10) 11821  12.19%  34.56% #########
# [ 10, 11) 13498  13.92%  48.47% ##########
# [ 11, 12) 13519  13.94%  62.41% ##########
# [ 12, 13) 12056  12.43%  74.84% #########
# [ 13, 14)  9637   9.94%  84.78% #######
# [ 14, 15)  7309   7.54%  92.31% #####
# [ 15, 15]  7458   7.69% 100.00% ######
#
# Number of training obs by leaf:
# Count: 96999 Average: 91.5381 StdDev: 387.744
# Min: 5 Max: 8610 Ignored: 0
# ----------------------------------------------
# [    5,  435) 92948  95.82%  95.82% ##########
# [  435,  865)  1893   1.95%  97.78%
# [  865, 1295)   661   0.68%  98.46%
# [ 1295, 1726)   392   0.40%  98.86%
# [ 1726, 2156)   231   0.24%  99.10%
# [ 2156, 2586)   182   0.19%  99.29%
# [ 2586, 3017)   153   0.16%  99.44%
# [ 3017, 3447)   131   0.14%  99.58%
# [ 3447, 3877)   145   0.15%  99.73%
# [ 3877, 4308)    90   0.09%  99.82%
# [ 4308, 4738)    66   0.07%  99.89%
# [ 4738, 5168)    44   0.05%  99.94%
# [ 5168, 5598)    30   0.03%  99.97%
# [ 5598, 6029)    12   0.01%  99.98%
# [ 6029, 6459)    10   0.01%  99.99%
# [ 6459, 6889)     3   0.00%  99.99%
# [ 6889, 7320)     3   0.00%  99.99%
# [ 7320, 7750)     2   0.00% 100.00%
# [ 7750, 8180)     1   0.00% 100.00%
# [ 8180, 8610]     2   0.00% 100.00%
#
# Attribute in nodes:
# 	4344 : Idn [NUMERICAL]
# 	3775 : Idmn [NUMERICAL]
# 	1939 : Skewness [NUMERICAL]
# 	1847 : Coarseness [NUMERICAL]
# 	1846 : Maximum [NUMERICAL]
# 	1809 : GrayLevelNonUniformity.2 [NUMERICAL]
# 	1652 : ClusterShade [NUMERICAL]
# 	1636 : Busyness [NUMERICAL]
# 	1521 : Correlation [NUMERICAL]
# 	1469 : Median [NUMERICAL]
# 	1441 : LargeDependenceHighGrayLevelEmphasis [NUMERICAL]
# 	1428 : LongRunHighGrayLevelEmphasis [NUMERICAL]
# 	1334 : MCC [NUMERICAL]
# 	1326 : Contrast.1 [NUMERICAL]
# 	1297 : Kurtosis [NUMERICAL]
# 	1231 : DifferenceVariance [NUMERICAL]
# 	1163 : 90Percentile [NUMERICAL]
# 	1156 : DifferenceEntropy [NUMERICAL]
# 	1136 : Range [NUMERICAL]
# 	1132 : Contrast [NUMERICAL]
# 	1131 : DependenceEntropy [NUMERICAL]
# 	1126 : SmallDependenceLowGrayLevelEmphasis [NUMERICAL]
# 	1116 : SmallAreaHighGrayLevelEmphasis [NUMERICAL]
# 	1111 : SmallAreaLowGrayLevelEmphasis [NUMERICAL]
# 	1087 : LargeAreaHighGrayLevelEmphasis [NUMERICAL]
# 	1072 : HighGrayLevelZoneEmphasis [NUMERICAL]
# 	1062 : Imc1 [NUMERICAL]
# 	1058 : InverseVariance [NUMERICAL]
# 	1050 : DifferenceAverage [NUMERICAL]
# 	1048 : Strength [NUMERICAL]
# 	1042 : LowGrayLevelZoneEmphasis [NUMERICAL]
# 	1012 : SmallDependenceHighGrayLevelEmphasis [NUMERICAL]
# 	1012 : Minimum [NUMERICAL]
# 	992 : 10Percentile [NUMERICAL]
# 	960 : Autocorrelation [NUMERICAL]
# 	953 : ZoneEntropy [NUMERICAL]
# 	953 : RobustMeanAbsoluteDeviation [NUMERICAL]
# 	949 : Complexity [NUMERICAL]
# 	945 : SmallDependenceEmphasis [NUMERICAL]
# 	940 : SumAverage [NUMERICAL]
# 	919 : SizeZoneNonUniformity [NUMERICAL]
# 	913 : SizeZoneNonUniformityNormalized [NUMERICAL]
# 	912 : Imc2 [NUMERICAL]
# 	910 : SmallAreaEmphasis [NUMERICAL]
# 	907 : GrayLevelVariance.2 [NUMERICAL]
# 	902 : Mean [NUMERICAL]
# 	902 : JointAverage [NUMERICAL]
# 	897 : DependenceVariance [NUMERICAL]
# 	891 : InterquartileRange [NUMERICAL]
# 	880 : SumEntropy [NUMERICAL]
# 	879 : LargeDependenceLowGrayLevelEmphasis [NUMERICAL]
# 	871 : Id [NUMERICAL]
# 	870 : ShortRunLowGrayLevelEmphasis [NUMERICAL]
# 	870 : LowGrayLevelEmphasis [NUMERICAL]
# 	863 : LongRunLowGrayLevelEmphasis [NUMERICAL]
# 	862 : TotalEnergy [NUMERICAL]
# 	845 : LargeDependenceEmphasis [NUMERICAL]
# 	838 : RootMeanSquared [NUMERICAL]
# 	838 : LargeAreaLowGrayLevelEmphasis [NUMERICAL]
# 	833 : RunVariance [NUMERICAL]
# 	830 : Energy [NUMERICAL]
# 	825 : LongRunEmphasis [NUMERICAL]
# 	824 : MaximumProbability [NUMERICAL]
# 	812 : LowGrayLevelRunEmphasis [NUMERICAL]
# 	805 : Idm [NUMERICAL]
# 	801 : HighGrayLevelEmphasis [NUMERICAL]
# 	791 : ShortRunHighGrayLevelEmphasis [NUMERICAL]
# 	788 : RunEntropy [NUMERICAL]
# 	779 : ClusterTendency [NUMERICAL]
# 	770 : HighGrayLevelRunEmphasis [NUMERICAL]
# 	770 : GrayLevelNonUniformity [NUMERICAL]
# 	769 : GrayLevelNonUniformityNormalized.1 [NUMERICAL]
# 	765 : ClusterProminence [NUMERICAL]
# 	757 : Uniformity [NUMERICAL]
# 	745 : DependenceNonUniformity [NUMERICAL]
# 	740 : ZonePercentage [NUMERICAL]
# 	736 : GrayLevelNonUniformityNormalized [NUMERICAL]
# 	730 : GrayLevelNonUniformity.1 [NUMERICAL]
# 	716 : JointEnergy [NUMERICAL]
# 	714 : DependenceNonUniformityNormalized [NUMERICAL]
# 	710 : RunPercentage [NUMERICAL]
# 	700 : Entropy [NUMERICAL]
# 	697 : ZoneVariance [NUMERICAL]
# 	677 : LargeAreaEmphasis [NUMERICAL]
# 	665 : RunLengthNonUniformityNormalized [NUMERICAL]
# 	662 : MeanAbsoluteDeviation [NUMERICAL]
# 	660 : RunLengthNonUniformity [NUMERICAL]
# 	658 : ShortRunEmphasis [NUMERICAL]
# 	650 : SumSquares [NUMERICAL]
# 	639 : JointEntropy [NUMERICAL]
# 	638 : GrayLevelVariance.1 [NUMERICAL]
# 	593 : Variance [NUMERICAL]
# 	580 : GrayLevelVariance [NUMERICAL]
#
# Attribute in nodes with depth <= 0:
# 	43 : LongRunHighGrayLevelEmphasis [NUMERICAL]
# 	27 : HighGrayLevelZoneEmphasis [NUMERICAL]
# 	23 : 90Percentile [NUMERICAL]
# 	20 : TotalEnergy [NUMERICAL]
# 	20 : Mean [NUMERICAL]
# 	18 : Energy [NUMERICAL]
# 	17 : HighGrayLevelEmphasis [NUMERICAL]
# 	15 : RootMeanSquared [NUMERICAL]
# 	15 : HighGrayLevelRunEmphasis [NUMERICAL]
# 	12 : Autocorrelation [NUMERICAL]
# 	10 : ShortRunHighGrayLevelEmphasis [NUMERICAL]
# 	10 : LowGrayLevelZoneEmphasis [NUMERICAL]
# 	10 : JointAverage [NUMERICAL]
# 	9 : SumAverage [NUMERICAL]
# 	8 : SmallAreaHighGrayLevelEmphasis [NUMERICAL]
# 	8 : Median [NUMERICAL]
# 	7 : Maximum [NUMERICAL]
# 	5 : ShortRunLowGrayLevelEmphasis [NUMERICAL]
# 	5 : LowGrayLevelEmphasis [NUMERICAL]
# 	3 : SmallAreaLowGrayLevelEmphasis [NUMERICAL]
# 	3 : LongRunLowGrayLevelEmphasis [NUMERICAL]
# 	2 : SmallDependenceLowGrayLevelEmphasis [NUMERICAL]
# 	2 : LargeDependenceHighGrayLevelEmphasis [NUMERICAL]
# 	2 : 10Percentile [NUMERICAL]
# 	1 : ZoneEntropy [NUMERICAL]
# 	1 : MCC [NUMERICAL]
# 	1 : LowGrayLevelRunEmphasis [NUMERICAL]
# 	1 : LargeDependenceLowGrayLevelEmphasis [NUMERICAL]
# 	1 : LargeAreaLowGrayLevelEmphasis [NUMERICAL]
# 	1 : Busyness [NUMERICAL]
#
# Attribute in nodes with depth <= 1:
# 	121 : LongRunHighGrayLevelEmphasis [NUMERICAL]
# 	43 : Mean [NUMERICAL]
# 	41 : Autocorrelation [NUMERICAL]
# 	40 : 90Percentile [NUMERICAL]
# 	39 : HighGrayLevelEmphasis [NUMERICAL]
# 	38 : RootMeanSquared [NUMERICAL]
# 	38 : Median [NUMERICAL]
# 	38 : JointAverage [NUMERICAL]
# 	38 : Energy [NUMERICAL]
# 	37 : TotalEnergy [NUMERICAL]
# 	37 : SumAverage [NUMERICAL]
# 	37 : HighGrayLevelZoneEmphasis [NUMERICAL]
# 	33 : LargeDependenceHighGrayLevelEmphasis [NUMERICAL]
# 	27 : HighGrayLevelRunEmphasis [NUMERICAL]
# 	25 : SmallDependenceLowGrayLevelEmphasis [NUMERICAL]
# 	22 : ShortRunLowGrayLevelEmphasis [NUMERICAL]
# 	22 : LargeAreaHighGrayLevelEmphasis [NUMERICAL]
# 	21 : ShortRunHighGrayLevelEmphasis [NUMERICAL]
# 	19 : LowGrayLevelEmphasis [NUMERICAL]
# 	18 : LowGrayLevelZoneEmphasis [NUMERICAL]
# 	18 : GrayLevelNonUniformity.2 [NUMERICAL]
# 	18 : Coarseness [NUMERICAL]
# 	16 : LongRunLowGrayLevelEmphasis [NUMERICAL]
# 	15 : Maximum [NUMERICAL]
# 	13 : SmallAreaLowGrayLevelEmphasis [NUMERICAL]
# 	12 : 10Percentile [NUMERICAL]
# 	11 : LowGrayLevelRunEmphasis [NUMERICAL]
# 	11 : LargeDependenceLowGrayLevelEmphasis [NUMERICAL]
# 	9 : SmallAreaHighGrayLevelEmphasis [NUMERICAL]
# 	9 : Busyness [NUMERICAL]
# 	7 : InverseVariance [NUMERICAL]
# 	5 : Minimum [NUMERICAL]
# 	4 : DifferenceEntropy [NUMERICAL]
# 	3 : SmallDependenceEmphasis [NUMERICAL]
# 	2 : ZonePercentage [NUMERICAL]
# 	2 : SmallDependenceHighGrayLevelEmphasis [NUMERICAL]
# 	2 : LargeAreaLowGrayLevelEmphasis [NUMERICAL]
# 	1 : ZoneEntropy [NUMERICAL]
# 	1 : SmallAreaEmphasis [NUMERICAL]
# 	1 : MCC [NUMERICAL]
# 	1 : Imc2 [NUMERICAL]
# 	1 : Idm [NUMERICAL]
# 	1 : GrayLevelNonUniformity.1 [NUMERICAL]
# 	1 : GrayLevelNonUniformity [NUMERICAL]
# 	1 : DifferenceVariance [NUMERICAL]
# 	1 : DependenceNonUniformityNormalized [NUMERICAL]
#
# Attribute in nodes with depth <= 2:
# 	191 : LongRunHighGrayLevelEmphasis [NUMERICAL]
# 	105 : Median [NUMERICAL]
# 	88 : SumAverage [NUMERICAL]
# 	87 : Autocorrelation [NUMERICAL]
# 	81 : Mean [NUMERICAL]
# 	80 : 90Percentile [NUMERICAL]
# 	75 : JointAverage [NUMERICAL]
# 	72 : TotalEnergy [NUMERICAL]
# 	71 : HighGrayLevelEmphasis [NUMERICAL]
# 	69 : Energy [NUMERICAL]
# 	68 : RootMeanSquared [NUMERICAL]
# 	68 : LargeDependenceHighGrayLevelEmphasis [NUMERICAL]
# 	66 : GrayLevelNonUniformity.2 [NUMERICAL]
# 	63 : Coarseness [NUMERICAL]
# 	52 : HighGrayLevelZoneEmphasis [NUMERICAL]
# 	46 : LargeAreaHighGrayLevelEmphasis [NUMERICAL]
# 	45 : SmallDependenceLowGrayLevelEmphasis [NUMERICAL]
# 	45 : LowGrayLevelEmphasis [NUMERICAL]
# 	43 : HighGrayLevelRunEmphasis [NUMERICAL]
# 	42 : Busyness [NUMERICAL]
# 	41 : Maximum [NUMERICAL]
# 	40 : ShortRunLowGrayLevelEmphasis [NUMERICAL]
# 	40 : ShortRunHighGrayLevelEmphasis [NUMERICAL]
# 	32 : LongRunLowGrayLevelEmphasis [NUMERICAL]
# 	30 : LowGrayLevelRunEmphasis [NUMERICAL]
# 	28 : LowGrayLevelZoneEmphasis [NUMERICAL]
# 	24 : LargeDependenceLowGrayLevelEmphasis [NUMERICAL]
# 	21 : Correlation [NUMERICAL]
# 	20 : InverseVariance [NUMERICAL]
# 	19 : 10Percentile [NUMERICAL]
# 	17 : SmallAreaLowGrayLevelEmphasis [NUMERICAL]
# 	17 : DependenceNonUniformityNormalized [NUMERICAL]
# 	15 : ClusterShade [NUMERICAL]
# 	13 : SmallAreaHighGrayLevelEmphasis [NUMERICAL]
# 	13 : Skewness [NUMERICAL]
# 	12 : SmallDependenceHighGrayLevelEmphasis [NUMERICAL]
# 	12 : RunPercentage [NUMERICAL]
# 	12 : Minimum [NUMERICAL]
# 	12 : LongRunEmphasis [NUMERICAL]
# 	12 : Idn [NUMERICAL]
# 	11 : SmallDependenceEmphasis [NUMERICAL]
# 	11 : ShortRunEmphasis [NUMERICAL]
# 	11 : LargeAreaLowGrayLevelEmphasis [NUMERICAL]
# 	11 : DependenceNonUniformity [NUMERICAL]
# 	10 : LargeDependenceEmphasis [NUMERICAL]
# 	10 : Idm [NUMERICAL]
# 	9 : ZonePercentage [NUMERICAL]
# 	8 : RunVariance [NUMERICAL]
# 	8 : Id [NUMERICAL]
# 	8 : DependenceEntropy [NUMERICAL]
# 	7 : RunLengthNonUniformityNormalized [NUMERICAL]
# 	7 : MCC [NUMERICAL]
# 	7 : Imc1 [NUMERICAL]
# 	7 : Idmn [NUMERICAL]
# 	6 : SumEntropy [NUMERICAL]
# 	6 : Imc2 [NUMERICAL]
# 	6 : DifferenceEntropy [NUMERICAL]
# 	6 : Contrast.1 [NUMERICAL]
# 	5 : GrayLevelNonUniformity.1 [NUMERICAL]
# 	5 : Complexity [NUMERICAL]
# 	4 : Strength [NUMERICAL]
# 	4 : SizeZoneNonUniformity [NUMERICAL]
# 	4 : RunLengthNonUniformity [NUMERICAL]
# 	4 : LargeAreaEmphasis [NUMERICAL]
# 	4 : GrayLevelNonUniformity [NUMERICAL]
# 	3 : ZoneVariance [NUMERICAL]
# 	3 : Uniformity [NUMERICAL]
# 	3 : DifferenceVariance [NUMERICAL]
# 	3 : ClusterTendency [NUMERICAL]
# 	2 : InterquartileRange [NUMERICAL]
# 	2 : GrayLevelNonUniformityNormalized [NUMERICAL]
# 	2 : DependenceVariance [NUMERICAL]
# 	1 : ZoneEntropy [NUMERICAL]
# 	1 : SumSquares [NUMERICAL]
# 	1 : SmallAreaEmphasis [NUMERICAL]
# 	1 : SizeZoneNonUniformityNormalized [NUMERICAL]
# 	1 : RunEntropy [NUMERICAL]
# 	1 : Range [NUMERICAL]
# 	1 : MaximumProbability [NUMERICAL]
# 	1 : Kurtosis [NUMERICAL]
# 	1 : JointEntropy [NUMERICAL]
# 	1 : GrayLevelVariance.2 [NUMERICAL]
# 	1 : GrayLevelVariance [NUMERICAL]
# 	1 : DifferenceAverage [NUMERICAL]
# 	1 : ClusterProminence [NUMERICAL]
#
# Attribute in nodes with depth <= 3:
# 	246 : LongRunHighGrayLevelEmphasis [NUMERICAL]
# 	171 : Median [NUMERICAL]
# 	153 : GrayLevelNonUniformity.2 [NUMERICAL]
# 	149 : Coarseness [NUMERICAL]
# 	142 : LargeDependenceHighGrayLevelEmphasis [NUMERICAL]
# 	133 : SumAverage [NUMERICAL]
# 	125 : 90Percentile [NUMERICAL]
# 	122 : Autocorrelation [NUMERICAL]
# 	109 : JointAverage [NUMERICAL]
# 	107 : Mean [NUMERICAL]
# 	104 : Busyness [NUMERICAL]
# 	98 : Maximum [NUMERICAL]
# 	96 : TotalEnergy [NUMERICAL]
# 	94 : HighGrayLevelEmphasis [NUMERICAL]
# 	94 : Energy [NUMERICAL]
# 	91 : RootMeanSquared [NUMERICAL]
# 	80 : SmallDependenceLowGrayLevelEmphasis [NUMERICAL]
# 	80 : ShortRunLowGrayLevelEmphasis [NUMERICAL]
# 	80 : LargeAreaHighGrayLevelEmphasis [NUMERICAL]
# 	79 : HighGrayLevelZoneEmphasis [NUMERICAL]
# 	77 : Idn [NUMERICAL]
# 	72 : LowGrayLevelEmphasis [NUMERICAL]
# 	70 : ClusterShade [NUMERICAL]
# 	65 : Skewness [NUMERICAL]
# 	65 : ShortRunHighGrayLevelEmphasis [NUMERICAL]
# 	65 : Idmn [NUMERICAL]
# 	62 : LowGrayLevelRunEmphasis [NUMERICAL]
# 	62 : HighGrayLevelRunEmphasis [NUMERICAL]
# 	59 : Correlation [NUMERICAL]
# 	53 : LongRunLowGrayLevelEmphasis [NUMERICAL]
# 	49 : SmallAreaLowGrayLevelEmphasis [NUMERICAL]
# 	49 : LowGrayLevelZoneEmphasis [NUMERICAL]
# 	48 : MCC [NUMERICAL]
# 	47 : InverseVariance [NUMERICAL]
# 	41 : SmallDependenceHighGrayLevelEmphasis [NUMERICAL]
# 	41 : 10Percentile [NUMERICAL]
# 	40 : Imc1 [NUMERICAL]
# 	39 : DependenceNonUniformityNormalized [NUMERICAL]
# 	38 : DependenceEntropy [NUMERICAL]
# 	35 : SmallAreaHighGrayLevelEmphasis [NUMERICAL]
# 	33 : LargeDependenceLowGrayLevelEmphasis [NUMERICAL]
# 	31 : SmallDependenceEmphasis [NUMERICAL]
# 	31 : Minimum [NUMERICAL]
# 	30 : Imc2 [NUMERICAL]
# 	30 : DifferenceVariance [NUMERICAL]
# 	28 : LongRunEmphasis [NUMERICAL]
# 	28 : LargeDependenceEmphasis [NUMERICAL]
# 	27 : RunPercentage [NUMERICAL]
# 	27 : DependenceNonUniformity [NUMERICAL]
# 	25 : Id [NUMERICAL]
# 	25 : DifferenceEntropy [NUMERICAL]
# 	24 : Idm [NUMERICAL]
# 	24 : DifferenceAverage [NUMERICAL]
# 	23 : RunLengthNonUniformityNormalized [NUMERICAL]
# 	22 : ShortRunEmphasis [NUMERICAL]
# 	22 : GrayLevelNonUniformity.1 [NUMERICAL]
# 	21 : Strength [NUMERICAL]
# 	21 : RunLengthNonUniformity [NUMERICAL]
# 	20 : Uniformity [NUMERICAL]
# 	20 : GrayLevelNonUniformity [NUMERICAL]
# 	20 : Contrast.1 [NUMERICAL]
# 	19 : RunVariance [NUMERICAL]
# 	19 : Range [NUMERICAL]
# 	18 : SizeZoneNonUniformity [NUMERICAL]
# 	17 : ZonePercentage [NUMERICAL]
# 	17 : SumEntropy [NUMERICAL]
# 	17 : MaximumProbability [NUMERICAL]
# 	17 : LargeAreaLowGrayLevelEmphasis [NUMERICAL]
# 	17 : InterquartileRange [NUMERICAL]
# 	17 : Complexity [NUMERICAL]
# 	16 : GrayLevelVariance.2 [NUMERICAL]
# 	16 : Contrast [NUMERICAL]
# 	15 : Kurtosis [NUMERICAL]
# 	15 : DependenceVariance [NUMERICAL]
# 	14 : ZoneEntropy [NUMERICAL]
# 	14 : RobustMeanAbsoluteDeviation [NUMERICAL]
# 	14 : ClusterTendency [NUMERICAL]
# 	12 : GrayLevelVariance.1 [NUMERICAL]
# 	12 : ClusterProminence [NUMERICAL]
# 	11 : GrayLevelNonUniformityNormalized.1 [NUMERICAL]
# 	11 : Entropy [NUMERICAL]
# 	10 : Variance [NUMERICAL]
# 	10 : SumSquares [NUMERICAL]
# 	10 : RunEntropy [NUMERICAL]
# 	10 : LargeAreaEmphasis [NUMERICAL]
# 	10 : GrayLevelNonUniformityNormalized [NUMERICAL]
# 	9 : ZoneVariance [NUMERICAL]
# 	9 : MeanAbsoluteDeviation [NUMERICAL]
# 	7 : GrayLevelVariance [NUMERICAL]
# 	6 : SmallAreaEmphasis [NUMERICAL]
# 	6 : JointEnergy [NUMERICAL]
# 	4 : SizeZoneNonUniformityNormalized [NUMERICAL]
# 	3 : JointEntropy [NUMERICAL]
#
# Attribute in nodes with depth <= 5:
# 	534 : Idn [NUMERICAL]
# 	520 : Idmn [NUMERICAL]
# 	439 : GrayLevelNonUniformity.2 [NUMERICAL]
# 	397 : Coarseness [NUMERICAL]
# 	388 : LongRunHighGrayLevelEmphasis [NUMERICAL]
# 	381 : Maximum [NUMERICAL]
# 	360 : Skewness [NUMERICAL]
# 	351 : Median [NUMERICAL]
# 	329 : LargeDependenceHighGrayLevelEmphasis [NUMERICAL]
# 	316 : Busyness [NUMERICAL]
# 	303 : ClusterShade [NUMERICAL]
# 	256 : 90Percentile [NUMERICAL]
# 	252 : SumAverage [NUMERICAL]
# 	238 : Autocorrelation [NUMERICAL]
# 	228 : Correlation [NUMERICAL]
# 	214 : Mean [NUMERICAL]
# 	213 : JointAverage [NUMERICAL]
# 	201 : SmallDependenceLowGrayLevelEmphasis [NUMERICAL]
# 	201 : MCC [NUMERICAL]
# 	200 : HighGrayLevelZoneEmphasis [NUMERICAL]
# 	197 : LargeAreaHighGrayLevelEmphasis [NUMERICAL]
# 	191 : ShortRunLowGrayLevelEmphasis [NUMERICAL]
# 	191 : HighGrayLevelEmphasis [NUMERICAL]
# 	191 : Energy [NUMERICAL]
# 	190 : TotalEnergy [NUMERICAL]
# 	189 : RootMeanSquared [NUMERICAL]
# 	177 : SmallAreaLowGrayLevelEmphasis [NUMERICAL]
# 	171 : LowGrayLevelEmphasis [NUMERICAL]
# 	167 : Kurtosis [NUMERICAL]
# 	167 : DependenceEntropy [NUMERICAL]
# 	164 : LowGrayLevelRunEmphasis [NUMERICAL]
# 	161 : SmallAreaHighGrayLevelEmphasis [NUMERICAL]
# 	161 : LowGrayLevelZoneEmphasis [NUMERICAL]
# 	158 : HighGrayLevelRunEmphasis [NUMERICAL]
# 	157 : ShortRunHighGrayLevelEmphasis [NUMERICAL]
# 	156 : LongRunLowGrayLevelEmphasis [NUMERICAL]
# 	152 : Imc1 [NUMERICAL]
# 	151 : SmallDependenceHighGrayLevelEmphasis [NUMERICAL]
# 	145 : InverseVariance [NUMERICAL]
# 	144 : DifferenceVariance [NUMERICAL]
# 	138 : 10Percentile [NUMERICAL]
# 	134 : Range [NUMERICAL]
# 	133 : Minimum [NUMERICAL]
# 	133 : DifferenceEntropy [NUMERICAL]
# 	131 : Imc2 [NUMERICAL]
# 	128 : SmallDependenceEmphasis [NUMERICAL]
# 	125 : Contrast.1 [NUMERICAL]
# 	124 : LargeDependenceLowGrayLevelEmphasis [NUMERICAL]
# 	120 : Strength [NUMERICAL]
# 	118 : Id [NUMERICAL]
# 	116 : LargeDependenceEmphasis [NUMERICAL]
# 	113 : LongRunEmphasis [NUMERICAL]
# 	110 : Contrast [NUMERICAL]
# 	109 : SumEntropy [NUMERICAL]
# 	109 : RunVariance [NUMERICAL]
# 	106 : SizeZoneNonUniformity [NUMERICAL]
# 	104 : DifferenceAverage [NUMERICAL]
# 	102 : Complexity [NUMERICAL]
# 	101 : DependenceNonUniformityNormalized [NUMERICAL]
# 	98 : RunPercentage [NUMERICAL]
# 	97 : GrayLevelVariance.2 [NUMERICAL]
# 	97 : DependenceNonUniformity [NUMERICAL]
# 	95 : InterquartileRange [NUMERICAL]
# 	92 : LargeAreaLowGrayLevelEmphasis [NUMERICAL]
# 	90 : Idm [NUMERICAL]
# 	85 : ZonePercentage [NUMERICAL]
# 	82 : RunEntropy [NUMERICAL]
# 	82 : GrayLevelNonUniformity.1 [NUMERICAL]
# 	80 : ZoneEntropy [NUMERICAL]
# 	80 : RunLengthNonUniformityNormalized [NUMERICAL]
# 	79 : RunLengthNonUniformity [NUMERICAL]
# 	76 : DependenceVariance [NUMERICAL]
# 	75 : RobustMeanAbsoluteDeviation [NUMERICAL]
# 	75 : GrayLevelNonUniformity [NUMERICAL]
# 	74 : ClusterTendency [NUMERICAL]
# 	72 : Entropy [NUMERICAL]
# 	71 : Uniformity [NUMERICAL]
# 	68 : ShortRunEmphasis [NUMERICAL]
# 	67 : GrayLevelVariance.1 [NUMERICAL]
# 	66 : SizeZoneNonUniformityNormalized [NUMERICAL]
# 	66 : MaximumProbability [NUMERICAL]
# 	66 : GrayLevelNonUniformityNormalized [NUMERICAL]
# 	64 : ClusterProminence [NUMERICAL]
# 	63 : MeanAbsoluteDeviation [NUMERICAL]
# 	62 : SmallAreaEmphasis [NUMERICAL]
# 	61 : GrayLevelNonUniformityNormalized.1 [NUMERICAL]
# 	54 : Variance [NUMERICAL]
# 	52 : LargeAreaEmphasis [NUMERICAL]
# 	47 : ZoneVariance [NUMERICAL]
# 	46 : JointEnergy [NUMERICAL]
# 	43 : JointEntropy [NUMERICAL]
# 	42 : SumSquares [NUMERICAL]
# 	38 : GrayLevelVariance [NUMERICAL]
#
# Condition type in nodes:
# 	96699 : HigherCondition
# Condition type in nodes with depth <= 0:
# 	300 : HigherCondition
# Condition type in nodes with depth <= 1:
# 	900 : HigherCondition
# Condition type in nodes with depth <= 2:
# 	2097 : HigherCondition
# Condition type in nodes with depth <= 3:
# 	4364 : HigherCondition
# Condition type in nodes with depth <= 5:
# 	14360 : HigherCondition
# Node format: NOT_SET
#
# Training OOB:
# 	trees: 1, Out-of-bag evaluation: accuracy:0.865836 logloss:4.83576
# 	trees: 11, Out-of-bag evaluation: accuracy:0.874089 logloss:1.74887
# 	trees: 21, Out-of-bag evaluation: accuracy:0.884562 logloss:1.05799
# 	trees: 31, Out-of-bag evaluation: accuracy:0.891839 logloss:0.781228
# 	trees: 41, Out-of-bag evaluation: accuracy:0.892624 logloss:0.612635
# 	trees: 51, Out-of-bag evaluation: accuracy:0.893273 logloss:0.54844
# 	trees: 61, Out-of-bag evaluation: accuracy:0.89432 logloss:0.506073
# 	trees: 71, Out-of-bag evaluation: accuracy:0.892353 logloss:0.487423
# 	trees: 81, Out-of-bag evaluation: accuracy:0.894482 logloss:0.435481
# 	trees: 91, Out-of-bag evaluation: accuracy:0.893734 logloss:0.382859
# 	trees: 101, Out-of-bag evaluation: accuracy:0.893544 logloss:0.36567
# 	trees: 111, Out-of-bag evaluation: accuracy:0.894871 logloss:0.346726
# 	trees: 121, Out-of-bag evaluation: accuracy:0.894834 logloss:0.338818
# 	trees: 131, Out-of-bag evaluation: accuracy:0.896062 logloss:0.321419
# 	trees: 141, Out-of-bag evaluation: accuracy:0.896007 logloss:0.321468
# 	trees: 151, Out-of-bag evaluation: accuracy:0.895277 logloss:0.321184
# 	trees: 161, Out-of-bag evaluation: accuracy:0.896044 logloss:0.320701
# 	trees: 171, Out-of-bag evaluation: accuracy:0.897 logloss:0.311914
# 	trees: 181, Out-of-bag evaluation: accuracy:0.898714 logloss:0.310388
# 	trees: 191, Out-of-bag evaluation: accuracy:0.89774 logloss:0.293775
# 	trees: 201, Out-of-bag evaluation: accuracy:0.897298 logloss:0.29329
# 	trees: 211, Out-of-bag evaluation: accuracy:0.896883 logloss:0.284466
# 	trees: 221, Out-of-bag evaluation: accuracy:0.896603 logloss:0.283664
# 	trees: 231, Out-of-bag evaluation: accuracy:0.897893 logloss:0.28414
# 	trees: 241, Out-of-bag evaluation: accuracy:0.897686 logloss:0.284197
# 	trees: 251, Out-of-bag evaluation: accuracy:0.897947 logloss:0.284131
# 	trees: 261, Out-of-bag evaluation: accuracy:0.897406 logloss:0.283654
# 	trees: 271, Out-of-bag evaluation: accuracy:0.898191 logloss:0.283578
# 	trees: 281, Out-of-bag evaluation: accuracy:0.897929 logloss:0.283556
# 	trees: 291, Out-of-bag evaluation: accuracy:0.898398 logloss:0.283207
# 	trees: 300, Out-of-bag evaluation: accuracy:0.899274 logloss:0.283194

# %%
# Model features
model.make_inspector().features()
# Out:
# ["10Percentile" (1; #0),
#  "90Percentile" (1; #1),
#  "Autocorrelation" (1; #2),
#  "Busyness" (1; #3),
#  "ClusterProminence" (1; #4),
#  "ClusterShade" (1; #5),
#  "ClusterTendency" (1; #6),
#  "Coarseness" (1; #7),
#  "Complexity" (1; #8),
#  "Contrast" (1; #9),
#  "Contrast.1" (1; #10),
#  "Correlation" (1; #11),
#  "DependenceEntropy" (1; #12),
#  "DependenceNonUniformity" (1; #13),
#  "DependenceNonUniformityNormalized" (1; #14),
#  "DependenceVariance" (1; #15),
#  "DifferenceAverage" (1; #16),
#  "DifferenceEntropy" (1; #17),
#  "DifferenceVariance" (1; #18),
#  "Energy" (1; #19),
#  "Entropy" (1; #20),
#  "GrayLevelNonUniformity" (1; #21),
#  "GrayLevelNonUniformity.1" (1; #22),
#  "GrayLevelNonUniformity.2" (1; #23),
#  "GrayLevelNonUniformityNormalized" (1; #24),
#  "GrayLevelNonUniformityNormalized.1" (1; #25),
#  "GrayLevelVariance" (1; #26),
#  "GrayLevelVariance.1" (1; #27),
#  "GrayLevelVariance.2" (1; #28),
#  "HighGrayLevelEmphasis" (1; #29),
#  "HighGrayLevelRunEmphasis" (1; #30),
#  "HighGrayLevelZoneEmphasis" (1; #31),
#  "Id" (1; #32),
#  "Idm" (1; #33),
#  "Idmn" (1; #34),
#  "Idn" (1; #35),
#  "Imc1" (1; #36),
#  "Imc2" (1; #37),
#  "InterquartileRange" (1; #38),
#  "InverseVariance" (1; #39),
#  "JointAverage" (1; #40),
#  "JointEnergy" (1; #41),
#  "JointEntropy" (1; #42),
#  "Kurtosis" (1; #43),
#  "LargeAreaEmphasis" (1; #44),
#  "LargeAreaHighGrayLevelEmphasis" (1; #45),
#  "LargeAreaLowGrayLevelEmphasis" (1; #46),
#  "LargeDependenceEmphasis" (1; #47),
#  "LargeDependenceHighGrayLevelEmphasis" (1; #48),
#  "LargeDependenceLowGrayLevelEmphasis" (1; #49),
#  "LongRunEmphasis" (1; #50),
#  "LongRunHighGrayLevelEmphasis" (1; #51),
#  "LongRunLowGrayLevelEmphasis" (1; #52),
#  "LowGrayLevelEmphasis" (1; #53),
#  "LowGrayLevelRunEmphasis" (1; #54),
#  "LowGrayLevelZoneEmphasis" (1; #55),
#  "MCC" (1; #56),
#  "Maximum" (1; #57),
#  "MaximumProbability" (1; #58),
#  "Mean" (1; #59),
#  "MeanAbsoluteDeviation" (1; #60),
#  "Median" (1; #61),
#  "Minimum" (1; #62),
#  "Range" (1; #63),
#  "RobustMeanAbsoluteDeviation" (1; #64),
#  "RootMeanSquared" (1; #65),
#  "RunEntropy" (1; #66),
#  "RunLengthNonUniformity" (1; #67),
#  "RunLengthNonUniformityNormalized" (1; #68),
#  "RunPercentage" (1; #69),
#  "RunVariance" (1; #70),
#  "ShortRunEmphasis" (1; #71),
#  "ShortRunHighGrayLevelEmphasis" (1; #72),
#  "ShortRunLowGrayLevelEmphasis" (1; #73),
#  "SizeZoneNonUniformity" (1; #74),
#  "SizeZoneNonUniformityNormalized" (1; #75),
#  "Skewness" (1; #76),
#  "SmallAreaEmphasis" (1; #77),
#  "SmallAreaHighGrayLevelEmphasis" (1; #78),
#  "SmallAreaLowGrayLevelEmphasis" (1; #79),
#  "SmallDependenceEmphasis" (1; #80),
#  "SmallDependenceHighGrayLevelEmphasis" (1; #81),
#  "SmallDependenceLowGrayLevelEmphasis" (1; #82),
#  "Strength" (1; #83),
#  "SumAverage" (1; #84),
#  "SumEntropy" (1; #85),
#  "SumSquares" (1; #86),
#  "TotalEnergy" (1; #87),
#  "Uniformity" (1; #88),
#  "Variance" (1; #89),
#  "ZoneEntropy" (1; #90),
#  "ZonePercentage" (1; #91),
#  "ZoneVariance" (1; #92)]

# %%
# Feature importance
model.make_inspector().variable_importances()
# Out:
# {'INV_MEAN_MIN_DEPTH': [("LongRunHighGrayLevelEmphasis" (1; #51),
#    0.12337134285008629),
#   ("GrayLevelNonUniformity.2" (1; #23), 0.10587084775517704),
#   ("LargeDependenceHighGrayLevelEmphasis" (1; #48), 0.10328007629677433),
#   ("Coarseness" (1; #7), 0.10233106720919312),
#   ("90Percentile" (1; #1), 0.10125488796500243),
#   ("Median" (1; #61), 0.10090420658356405),
#   ("HighGrayLevelZoneEmphasis" (1; #31), 0.10011630436675041),
#   ("Idn" (1; #35), 0.09939408245512392),
#   ("Busyness" (1; #3), 0.09924005080590377),
#   ("Maximum" (1; #57), 0.09902745120431328),
#   ("Mean" (1; #59), 0.09897987492908417),
#   ("TotalEnergy" (1; #87), 0.09840970943016332),
#   ("Autocorrelation" (1; #2), 0.09793239366662825),
#   ("Idmn" (1; #34), 0.09782475691616098),
#   ("HighGrayLevelEmphasis" (1; #29), 0.09780805288712591),
#   ("RootMeanSquared" (1; #65), 0.09736912676371888),
#   ("Energy" (1; #19), 0.0972009165257087),
#   ("JointAverage" (1; #40), 0.09699811609440992),
#   ("SumAverage" (1; #84), 0.09611831750080385),
#   ("LargeAreaHighGrayLevelEmphasis" (1; #45), 0.09590426186320722),
#   ("SmallDependenceLowGrayLevelEmphasis" (1; #82), 0.09523709290247662),
#   ("HighGrayLevelRunEmphasis" (1; #30), 0.0945253847387787),
#   ("Skewness" (1; #76), 0.09441135921775047),
#   ("ShortRunLowGrayLevelEmphasis" (1; #73), 0.09434136256756068),
#   ("ShortRunHighGrayLevelEmphasis" (1; #72), 0.09369951486102517),
#   ("LowGrayLevelEmphasis" (1; #53), 0.093142792956643),
#   ("LowGrayLevelZoneEmphasis" (1; #55), 0.09301140425289309),
#   ("Correlation" (1; #11), 0.09269651607349705),
#   ("SmallAreaHighGrayLevelEmphasis" (1; #78), 0.09228573202486091),
#   ("LongRunLowGrayLevelEmphasis" (1; #52), 0.09218892145158808),
#   ("InverseVariance" (1; #39), 0.09194510026403978),
#   ("ClusterShade" (1; #5), 0.09188544055509339),
#   ("SmallAreaLowGrayLevelEmphasis" (1; #79), 0.09150127757925292),
#   ("LargeDependenceLowGrayLevelEmphasis" (1; #49), 0.09148699128377312),
#   ("10Percentile" (1; #0), 0.09135094120724514),
#   ("DependenceEntropy" (1; #12), 0.09122909195746953),
#   ("LowGrayLevelRunEmphasis" (1; #54), 0.09103319345803497),
#   ("MCC" (1; #56), 0.090805974364457),
#   ("SmallDependenceEmphasis" (1; #80), 0.09031511604570519),
#   ("DependenceNonUniformityNormalized" (1; #14), 0.09027302725713165),
#   ("Imc1" (1; #36), 0.09018495114316186),
#   ("LargeDependenceEmphasis" (1; #47), 0.0901548090424625),
#   ("SmallDependenceHighGrayLevelEmphasis" (1; #81), 0.09001688223971281),
#   ("LongRunEmphasis" (1; #50), 0.08997518367344344),
#   ("Minimum" (1; #62), 0.08991604397973621),
#   ("DifferenceEntropy" (1; #17), 0.08990266920142885),
#   ("RunVariance" (1; #70), 0.08963732176233206),
#   ("DifferenceVariance" (1; #18), 0.08962200048268697),
#   ("Strength" (1; #83), 0.08961307431109444),
#   ("ZonePercentage" (1; #91), 0.08953726711682307),
#   ("Idm" (1; #33), 0.08952205144572985),
#   ("RunPercentage" (1; #69), 0.08944624202234631),
#   ("Contrast.1" (1; #10), 0.08941925534053612),
#   ("Id" (1; #32), 0.08929833911293678),
#   ("DependenceNonUniformity" (1; #13), 0.08915412201719189),
#   ("Imc2" (1; #37), 0.08912723171534653),
#   ("RunLengthNonUniformityNormalized" (1; #68), 0.08907762962136008),
#   ("LargeAreaLowGrayLevelEmphasis" (1; #46), 0.08900301877742132),
#   ("Kurtosis" (1; #43), 0.08898258744069913),
#   ("ShortRunEmphasis" (1; #71), 0.08878066182593268),
#   ("RunLengthNonUniformity" (1; #67), 0.08875936917459804),
#   ("DifferenceAverage" (1; #16), 0.08872181325863913),
#   ("Contrast" (1; #9), 0.0887053351657135),
#   ("Range" (1; #63), 0.08865485632468238),
#   ("SumEntropy" (1; #85), 0.08862632374145386),
#   ("SizeZoneNonUniformity" (1; #74), 0.08855819152925457),
#   ("DependenceVariance" (1; #15), 0.08855377285047437),
#   ("GrayLevelNonUniformity.1" (1; #22), 0.08833531760371166),
#   ("Complexity" (1; #8), 0.08820073773201415),
#   ("GrayLevelNonUniformity" (1; #21), 0.08818362873801276),
#   ("RunEntropy" (1; #66), 0.08816428225703),
#   ("ZoneEntropy" (1; #90), 0.08807870786744901),
#   ("GrayLevelVariance.2" (1; #28), 0.08793624024211381),
#   ("InterquartileRange" (1; #38), 0.0879356597483036),
#   ("SmallAreaEmphasis" (1; #77), 0.08788531692919732),
#   ("Uniformity" (1; #88), 0.08787921161923218),
#   ("MaximumProbability" (1; #58), 0.08781886835030334),
#   ("LargeAreaEmphasis" (1; #44), 0.08775000946657786),
#   ("GrayLevelNonUniformityNormalized" (1; #24), 0.08773509810593803),
#   ("RobustMeanAbsoluteDeviation" (1; #64), 0.08773342063524012),
#   ("GrayLevelNonUniformityNormalized.1" (1; #25), 0.08770192357601207),
#   ("Entropy" (1; #20), 0.08769281625503966),
#   ("SizeZoneNonUniformityNormalized" (1; #75), 0.08766141238801484),
#   ("ClusterTendency" (1; #6), 0.08764203044852224),
#   ("ClusterProminence" (1; #4), 0.08754765170885682),
#   ("ZoneVariance" (1; #92), 0.0875158522986775),
#   ("GrayLevelVariance.1" (1; #27), 0.08750361641353799),
#   ("Variance" (1; #89), 0.08746698398061081),
#   ("JointEnergy" (1; #41), 0.08742706625652817),
#   ("JointEntropy" (1; #42), 0.08738175315400651),
#   ("MeanAbsoluteDeviation" (1; #60), 0.08725778607458824),
#   ("GrayLevelVariance" (1; #26), 0.08715823707632137),
#   ("SumSquares" (1; #86), 0.08712706468210185)],
#  'SUM_SCORE': [("LongRunHighGrayLevelEmphasis" (1; #51), 507157.0167601774),
#   ("HighGrayLevelZoneEmphasis" (1; #31), 255379.5916238326),
#   ("90Percentile" (1; #1), 243281.79917159246),
#   ("Mean" (1; #59), 206958.5625277332),
#   ("TotalEnergy" (1; #87), 204950.12814688997),
#   ("Idn" (1; #35), 194824.33484442),
#   ("Energy" (1; #19), 182567.30575477018),
#   ("HighGrayLevelEmphasis" (1; #29), 178448.9675179232),
#   ("RootMeanSquared" (1; #65), 169410.05101795422),
#   ("Idmn" (1; #34), 163974.57919199188),
#   ("Autocorrelation" (1; #2), 152170.55475892586),
#   ("HighGrayLevelRunEmphasis" (1; #30), 150480.16343033916),
#   ("LargeDependenceHighGrayLevelEmphasis" (1; #48), 146818.35541495116),
#   ("Median" (1; #61), 138835.46869860904),
#   ("Maximum" (1; #57), 138490.11221324574),
#   ("GrayLevelNonUniformity.2" (1; #23), 130944.04934179662),
#   ("JointAverage" (1; #40), 130447.59135937894),
#   ("SumAverage" (1; #84), 123347.12585126427),
#   ("ShortRunHighGrayLevelEmphasis" (1; #72), 117175.71728399782),
#   ("Coarseness" (1; #7), 105306.43919210133),
#   ("LowGrayLevelZoneEmphasis" (1; #55), 104367.72377877274),
#   ("Busyness" (1; #3), 102277.94571947698),
#   ("SmallAreaHighGrayLevelEmphasis" (1; #78), 93086.35128914627),
#   ("ShortRunLowGrayLevelEmphasis" (1; #73), 82757.96688235455),
#   ("LowGrayLevelEmphasis" (1; #53), 73429.9193506512),
#   ("SmallDependenceLowGrayLevelEmphasis" (1; #82), 72968.00796318617),
#   ("LargeAreaHighGrayLevelEmphasis" (1; #45), 71621.62013068258),
#   ("Skewness" (1; #76), 55146.552715392754),
#   ("SmallAreaLowGrayLevelEmphasis" (1; #79), 54583.36216809051),
#   ("LongRunLowGrayLevelEmphasis" (1; #52), 54347.555886371876),
#   ("Correlation" (1; #11), 48193.010679389845),
#   ("10Percentile" (1; #0), 46202.19717081427),
#   ("InverseVariance" (1; #39), 44103.795373213004),
#   ("DependenceEntropy" (1; #12), 42274.88822696916),
#   ("ClusterShade" (1; #5), 41103.59478090962),
#   ("LargeDependenceLowGrayLevelEmphasis" (1; #49), 40349.857998603096),
#   ("LowGrayLevelRunEmphasis" (1; #54), 38845.99417784593),
#   ("SmallDependenceEmphasis" (1; #80), 35975.836228513064),
#   ("DifferenceEntropy" (1; #17), 34926.984126364296),
#   ("MCC" (1; #56), 34010.95683788528),
#   ("SmallDependenceHighGrayLevelEmphasis" (1; #81), 33494.72938876214),
#   ("Contrast.1" (1; #10), 32482.863263262367),
#   ("Imc1" (1; #36), 31780.35303588403),
#   ("LargeDependenceEmphasis" (1; #47), 31572.478445407516),
#   ("DifferenceVariance" (1; #18), 30985.241194882463),
#   ("LongRunEmphasis" (1; #50), 30971.281823279478),
#   ("DependenceNonUniformityNormalized" (1; #14), 28576.037277735966),
#   ("RunVariance" (1; #70), 28538.992811816002),
#   ("Strength" (1; #83), 28283.323681350226),
#   ("DifferenceAverage" (1; #16), 27888.183863733437),
#   ("Idm" (1; #33), 27667.926617760488),
#   ("LargeAreaLowGrayLevelEmphasis" (1; #46), 27626.525346946066),
#   ("Minimum" (1; #62), 27367.246383179623),
#   ("Contrast" (1; #9), 27320.553172234017),
#   ("Id" (1; #32), 27117.501662281822),
#   ("RunPercentage" (1; #69), 26706.55749329466),
#   ("ZonePercentage" (1; #91), 26639.003612447243),
#   ("Imc2" (1; #37), 25579.934127253313),
#   ("DependenceNonUniformity" (1; #13), 25083.894840117042),
#   ("Range" (1; #63), 24048.428191442716),
#   ("RunLengthNonUniformityNormalized" (1; #68), 23567.1625784432),
#   ("SizeZoneNonUniformity" (1; #74), 22670.83839257308),
#   ("Kurtosis" (1; #43), 22529.35770326211),
#   ("DependenceVariance" (1; #15), 21448.494751957114),
#   ("SumEntropy" (1; #85), 21050.402257378075),
#   ("ShortRunEmphasis" (1; #71), 21022.873501595957),
#   ("RunLengthNonUniformity" (1; #67), 20238.984627203292),
#   ("ZoneEntropy" (1; #90), 19571.18920951366),
#   ("Complexity" (1; #8), 18420.16294361229),
#   ("RunEntropy" (1; #66), 18406.337946602205),
#   ("SmallAreaEmphasis" (1; #77), 17560.03371353433),
#   ("GrayLevelNonUniformity" (1; #21), 17508.03268268764),
#   ("RobustMeanAbsoluteDeviation" (1; #64), 17505.605285641166),
#   ("GrayLevelNonUniformity.1" (1; #22), 17273.19763405802),
#   ("SizeZoneNonUniformityNormalized" (1; #75), 17154.885122385116),
#   ("GrayLevelVariance.2" (1; #28), 17015.233975005012),
#   ("MaximumProbability" (1; #58), 16604.976280608396),
#   ("InterquartileRange" (1; #38), 16583.621000395484),
#   ("Uniformity" (1; #88), 16254.738264698402),
#   ("LargeAreaEmphasis" (1; #44), 16050.136196375895),
#   ("Entropy" (1; #20), 15388.115807722095),
#   ("ClusterTendency" (1; #6), 15289.289819942967),
#   ("GrayLevelNonUniformityNormalized.1" (1; #25), 15188.444727674314),
#   ("GrayLevelNonUniformityNormalized" (1; #24), 15158.469612430403),
#   ("JointEnergy" (1; #41), 13576.20427979127),
#   ("ClusterProminence" (1; #4), 13063.830705488888),
#   ("ZoneVariance" (1; #92), 13021.304099234067),
#   ("GrayLevelVariance.1" (1; #27), 12297.313045361534),
#   ("JointEntropy" (1; #42), 12292.54044347308),
#   ("Variance" (1; #89), 12280.906987970973),
#   ("MeanAbsoluteDeviation" (1; #60), 11936.432499910527),
#   ("SumSquares" (1; #86), 11291.339751968006),
#   ("GrayLevelVariance" (1; #26), 9981.180196574724)],
#  'NUM_AS_ROOT': [("LongRunHighGrayLevelEmphasis" (1; #51), 43.0),
#   ("HighGrayLevelZoneEmphasis" (1; #31), 27.0),
#   ("90Percentile" (1; #1), 23.0),
#   ("Mean" (1; #59), 20.0),
#   ("TotalEnergy" (1; #87), 20.0),
#   ("Energy" (1; #19), 18.0),
#   ("HighGrayLevelEmphasis" (1; #29), 17.0),
#   ("HighGrayLevelRunEmphasis" (1; #30), 15.0),
#   ("RootMeanSquared" (1; #65), 15.0),
#   ("Autocorrelation" (1; #2), 12.0),
#   ("JointAverage" (1; #40), 10.0),
#   ("LowGrayLevelZoneEmphasis" (1; #55), 10.0),
#   ("ShortRunHighGrayLevelEmphasis" (1; #72), 10.0),
#   ("SumAverage" (1; #84), 9.0),
#   ("Median" (1; #61), 8.0),
#   ("SmallAreaHighGrayLevelEmphasis" (1; #78), 8.0),
#   ("Maximum" (1; #57), 7.0),
#   ("LowGrayLevelEmphasis" (1; #53), 5.0),
#   ("ShortRunLowGrayLevelEmphasis" (1; #73), 5.0),
#   ("LongRunLowGrayLevelEmphasis" (1; #52), 3.0),
#   ("SmallAreaLowGrayLevelEmphasis" (1; #79), 3.0),
#   ("10Percentile" (1; #0), 2.0),
#   ("LargeDependenceHighGrayLevelEmphasis" (1; #48), 2.0),
#   ("SmallDependenceLowGrayLevelEmphasis" (1; #82), 2.0),
#   ("Busyness" (1; #3), 1.0),
#   ("LargeAreaLowGrayLevelEmphasis" (1; #46), 1.0),
#   ("LargeDependenceLowGrayLevelEmphasis" (1; #49), 1.0),
#   ("LowGrayLevelRunEmphasis" (1; #54), 1.0),
#   ("MCC" (1; #56), 1.0),
#   ("ZoneEntropy" (1; #90), 1.0)],
#  'NUM_NODES': [("Idn" (1; #35), 4344.0),
#   ("Idmn" (1; #34), 3775.0),
#   ("Skewness" (1; #76), 1939.0),
#   ("Coarseness" (1; #7), 1847.0),
#   ("Maximum" (1; #57), 1846.0),
#   ("GrayLevelNonUniformity.2" (1; #23), 1809.0),
#   ("ClusterShade" (1; #5), 1652.0),
#   ("Busyness" (1; #3), 1636.0),
#   ("Correlation" (1; #11), 1521.0),
#   ("Median" (1; #61), 1469.0),
#   ("LargeDependenceHighGrayLevelEmphasis" (1; #48), 1441.0),
#   ("LongRunHighGrayLevelEmphasis" (1; #51), 1428.0),
#   ("MCC" (1; #56), 1334.0),
#   ("Contrast.1" (1; #10), 1326.0),
#   ("Kurtosis" (1; #43), 1297.0),
#   ("DifferenceVariance" (1; #18), 1231.0),
#   ("90Percentile" (1; #1), 1163.0),
#   ("DifferenceEntropy" (1; #17), 1156.0),
#   ("Range" (1; #63), 1136.0),
#   ("Contrast" (1; #9), 1132.0),
#   ("DependenceEntropy" (1; #12), 1131.0),
#   ("SmallDependenceLowGrayLevelEmphasis" (1; #82), 1126.0),
#   ("SmallAreaHighGrayLevelEmphasis" (1; #78), 1116.0),
#   ("SmallAreaLowGrayLevelEmphasis" (1; #79), 1111.0),
#   ("LargeAreaHighGrayLevelEmphasis" (1; #45), 1087.0),
#   ("HighGrayLevelZoneEmphasis" (1; #31), 1072.0),
#   ("Imc1" (1; #36), 1062.0),
#   ("InverseVariance" (1; #39), 1058.0),
#   ("DifferenceAverage" (1; #16), 1050.0),
#   ("Strength" (1; #83), 1048.0),
#   ("LowGrayLevelZoneEmphasis" (1; #55), 1042.0),
#   ("Minimum" (1; #62), 1012.0),
#   ("SmallDependenceHighGrayLevelEmphasis" (1; #81), 1012.0),
#   ("10Percentile" (1; #0), 992.0),
#   ("Autocorrelation" (1; #2), 960.0),
#   ("RobustMeanAbsoluteDeviation" (1; #64), 953.0),
#   ("ZoneEntropy" (1; #90), 953.0),
#   ("Complexity" (1; #8), 949.0),
#   ("SmallDependenceEmphasis" (1; #80), 945.0),
#   ("SumAverage" (1; #84), 940.0),
#   ("SizeZoneNonUniformity" (1; #74), 919.0),
#   ("SizeZoneNonUniformityNormalized" (1; #75), 913.0),
#   ("Imc2" (1; #37), 912.0),
#   ("SmallAreaEmphasis" (1; #77), 910.0),
#   ("GrayLevelVariance.2" (1; #28), 907.0),
#   ("JointAverage" (1; #40), 902.0),
#   ("Mean" (1; #59), 902.0),
#   ("DependenceVariance" (1; #15), 897.0),
#   ("InterquartileRange" (1; #38), 891.0),
#   ("SumEntropy" (1; #85), 880.0),
#   ("LargeDependenceLowGrayLevelEmphasis" (1; #49), 879.0),
#   ("Id" (1; #32), 871.0),
#   ("LowGrayLevelEmphasis" (1; #53), 870.0),
#   ("ShortRunLowGrayLevelEmphasis" (1; #73), 870.0),
#   ("LongRunLowGrayLevelEmphasis" (1; #52), 863.0),
#   ("TotalEnergy" (1; #87), 862.0),
#   ("LargeDependenceEmphasis" (1; #47), 845.0),
#   ("LargeAreaLowGrayLevelEmphasis" (1; #46), 838.0),
#   ("RootMeanSquared" (1; #65), 838.0),
#   ("RunVariance" (1; #70), 833.0),
#   ("Energy" (1; #19), 830.0),
#   ("LongRunEmphasis" (1; #50), 825.0),
#   ("MaximumProbability" (1; #58), 824.0),
#   ("LowGrayLevelRunEmphasis" (1; #54), 812.0),
#   ("Idm" (1; #33), 805.0),
#   ("HighGrayLevelEmphasis" (1; #29), 801.0),
#   ("ShortRunHighGrayLevelEmphasis" (1; #72), 791.0),
#   ("RunEntropy" (1; #66), 788.0),
#   ("ClusterTendency" (1; #6), 779.0),
#   ("GrayLevelNonUniformity" (1; #21), 770.0),
#   ("HighGrayLevelRunEmphasis" (1; #30), 770.0),
#   ("GrayLevelNonUniformityNormalized.1" (1; #25), 769.0),
#   ("ClusterProminence" (1; #4), 765.0),
#   ("Uniformity" (1; #88), 757.0),
#   ("DependenceNonUniformity" (1; #13), 745.0),
#   ("ZonePercentage" (1; #91), 740.0),
#   ("GrayLevelNonUniformityNormalized" (1; #24), 736.0),
#   ("GrayLevelNonUniformity.1" (1; #22), 730.0),
#   ("JointEnergy" (1; #41), 716.0),
#   ("DependenceNonUniformityNormalized" (1; #14), 714.0),
#   ("RunPercentage" (1; #69), 710.0),
#   ("Entropy" (1; #20), 700.0),
#   ("ZoneVariance" (1; #92), 697.0),
#   ("LargeAreaEmphasis" (1; #44), 677.0),
#   ("RunLengthNonUniformityNormalized" (1; #68), 665.0),
#   ("MeanAbsoluteDeviation" (1; #60), 662.0),
#   ("RunLengthNonUniformity" (1; #67), 660.0),
#   ("ShortRunEmphasis" (1; #71), 658.0),
#   ("SumSquares" (1; #86), 650.0),
#   ("JointEntropy" (1; #42), 639.0),
#   ("GrayLevelVariance.1" (1; #27), 638.0),
#   ("Variance" (1; #89), 593.0),
#   ("GrayLevelVariance" (1; #26), 580.0)]}

# %%
# Model self evaluation
model.make_inspector().evaluation()
# Out:
# Evaluation(num_examples=29597, accuracy=0.899273544577225, loss=0.28319371002684723, rmse=None, ndcg=None, aucs=None, auuc=None, qini=None)

# %%
logs = model.make_inspector().training_logs()

plt.figure(figsize=(12, 4))
plt.subplot(1, 2, 1)
plt.plot([log.num_trees for log in logs], [log.evaluation.accuracy for log in logs])
plt.xlabel("Number of trees")
plt.ylabel("Accuracy (out-of-bag)")
plt.subplot(1, 2, 2)
plt.plot([log.num_trees for log in logs], [log.evaluation.loss for log in logs])
plt.xlabel("Number of trees")
plt.ylabel("Logloss (out-of-bag)")
plt.show()

# %% [markdown]
# Calculate the score of our hold-out validation dataset

# %%
predictions = model.predict(val_ds)
y_true      = validation_data["label"]

from sklearn.metrics import roc_auc_score
ROC_AUC = roc_auc_score(y_true, predictions)
print("The ROC AUC score is %.5f" % ROC_AUC )
# Out:
# 1/5 [=====>........................] - ETA: 0s
# 4/5 [=======================>......] - ETA: 0s
# 5/5 [==============================] - 0s 18ms/step
# The ROC AUC score is 0.99901

# %%
# Compute binary classification metrics with sklearn
import numpy as np
from sklearn.metrics import (
    accuracy_score,
    precision_score,
    recall_score,
    f1_score,
    roc_auc_score,
    average_precision_score,
    confusion_matrix,
    classification_report,
    matthews_corrcoef,
    log_loss,
    brier_score_loss,
)

# Get predictions (probabilities or class labels)
preds = model.predict(test_ds)
# If model outputs probabilities, convert to labels by threshold 0.5
if preds.ndim == 2:
    # For TFDF classification, preds may be class probabilities with shape (N, 2)
    if preds.shape[1] == 2:
        pos_probs = preds[:, 1]
    else:
        # If single-probability column (positive class)
        pos_probs = preds[:, -1]
    y_pred = (pos_probs >= 0.5).astype(int)
else:
    # Already class labels
    y_pred = preds.astype(int)
    pos_probs = None

# Ground truth labels (must be 0/1 integers)
y_true = test_data["label"].astype(int).to_numpy()

# Core metrics
metrics = {}
metrics["accuracy"] = accuracy_score(y_true, y_pred)
metrics["precision"] = precision_score(y_true, y_pred, zero_division=0)
metrics["recall"] = recall_score(y_true, y_pred, zero_division=0)
metrics["f1"] = f1_score(y_true, y_pred, zero_division=0)
metrics["mcc"] = matthews_corrcoef(y_true, y_pred)

# Probabilistic metrics (only if we have probabilities)
if pos_probs is not None:
    metrics["roc_auc"] = roc_auc_score(y_true, pos_probs)
    metrics["pr_auc"] = average_precision_score(y_true, pos_probs)
    metrics["log_loss"] = log_loss(y_true, pos_probs, labels=[0,1])
    metrics["brier_score"] = brier_score_loss(y_true, pos_probs)

# Confusion matrix and detailed report
cm = confusion_matrix(y_true, y_pred, labels=[0,1])
report = classification_report(y_true, y_pred, digits=4)

print("Sklearn binary metrics:")
for k, v in metrics.items():
    print(f"{k}: {v:.4f}")
print("\nConfusion matrix:\n", cm)
print("\nClassification report:\n", report)
# Out:
# 1/9 [==>...........................] - ETA: 1s
# 3/9 [=========>....................] - ETA: 0s
# 6/9 [===================>..........] - ETA: 0s
# 9/9 [==============================] - ETA: 0s
# 9/9 [==============================] - 0s 22ms/step
# Sklearn binary metrics:
# accuracy: 0.9675
# precision: 0.9003
# recall: 0.7565
# f1: 0.8222
# mcc: 0.8081
# roc_auc: 0.9757
# pr_auc: 0.9064
# log_loss: 0.0998
# brier_score: 0.0233
#
# Confusion matrix:
#  [[7937   74]
#  [ 215  668]]
#
# Classification report:
#                precision    recall  f1-score   support
#
#            0     0.9736    0.9908    0.9821      8011
#            1     0.9003    0.7565    0.8222       883
#
#     accuracy                         0.9675      8894
#    macro avg     0.9369    0.8736    0.9021      8894
# weighted avg     0.9663    0.9675    0.9662      8894
