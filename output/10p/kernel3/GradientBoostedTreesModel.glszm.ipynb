# %%
# Import packages and modules
import numpy  as np
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow_decision_forests as tfdf

from sklearn.model_selection import train_test_split
# Out:
# 2026-09-10 09:47:28.049850: I tensorflow/core/util/port.cc:113] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2026-09-10 09:47:28.400353: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2026-09-10 09:47:33.219273: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
# Check the version of TensorFlow Decision Forests
print("Found TensorFlow Decision Forests v" + tfdf.__version__)
# Out:
# Found TensorFlow Decision Forests v1.9.1

# %%
datasetPath = "dataset/10p/all/kernel3/"

# %%
# Parameters
datasetPath = "dataset/10p/glszm/kernel3/"

# %%
# train/validation/test = 70/10/20
train_data = pd.read_csv(f"{datasetPath}dataset.train.csv")
validation_data = pd.read_csv(f"{datasetPath}dataset.validation.csv")
test_data = pd.read_csv(f"{datasetPath}dataset.test.csv")

# %%
from sklearn.utils.class_weight import compute_class_weight

# tinh class weight tren tap train
classes = np.array([0, 1])
weights = compute_class_weight(class_weight="balanced", classes=classes, y=train_data["label"])
class_weight = {0: weights[0], 1: weights[1]}

# gan sample_weight cho tung dong
train_data["sample_weight"] = train_data["label"].map(class_weight)
validation_data["sample_weight"] = validation_data["label"].map(class_weight)
test_data["sample_weight"] = test_data["label"].map(class_weight)

# Convert the dataset into a TensorFlow dataset.
train_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    train_data, label="label", weight="sample_weight"
)         
val_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    validation_data, label="label", weight="sample_weight"
)
test_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    test_data, label="label", weight="sample_weight"
)
# Out:
# 2026-09-10 09:47:46.878208: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:984] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2026-09-10 09:47:46.880570: W tensorflow/core/common_runtime/gpu/gpu_device.cc:2251] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...

# %%
import keras

# %%
# %%time

# Train a Gradient Boosted Trees model.
model = tfdf.keras.GradientBoostedTreesModel()

# Add evaluation metrics
model.compile(
    metrics=["accuracy"]
)
model.fit(x=train_ds)

# # Train a Gradient Boosted Trees model.
# model = tfdf.keras.GradientBoostedTreesModel(num_trees=1500)
# model.fit(train_ds)
# Out:
# Use /tmp/tmprobat0cm as temporary training directory
# Reading training dataset...
# [WARNING 26-09-10 09:47:47.0520 UTC gradient_boosted_trees.cc:1840] "goss_alpha" set but "sampling_method" not equal to "GOSS".
# [WARNING 26-09-10 09:47:47.0524 UTC gradient_boosted_trees.cc:1851] "goss_beta" set but "sampling_method" not equal to "GOSS".
# [WARNING 26-09-10 09:47:47.0524 UTC gradient_boosted_trees.cc:1865] "selective_gradient_boosting_ratio" set but "sampling_method" not equal to "SELGB".
# Training dataset read in 0:00:02.930379. Found 29597 examples.
# Training model...
# Model trained in 0:00:02.484231
# Compiling model...
# [INFO 26-09-10 09:47:52.4943 UTC kernel.cc:1233] Loading model from path /tmp/tmprobat0cm/model/ with prefix 037d969dcf894d80
# [INFO 26-09-10 09:47:52.4989 UTC quick_scorer_extended.cc:911] The binary was compiled without AVX2 support, but your CPU supports it. Enable it for faster model inference.
# [INFO 26-09-10 09:47:52.4991 UTC abstract_model.cc:1362] Engine "GradientBoostedTreesQuickScorerExtended" built
# [INFO 26-09-10 09:47:52.4992 UTC kernel.cc:1061] Use fast generic engine
# Model compiled.
# CPU times: user 20.5 s, sys: 823 ms, total: 21.3 s
# Wall time: 9.28 s

# %%
# Evaluate the model
evaluate = model.evaluate(val_ds, return_dict=True)
print()

for name, value in evaluate.items():
    print(f"{name}: {value:.4f}")
# Out:
# WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 1/5 [=====>........................] - ETA: 13s - loss: 0.0000e+00 - accuracy: 0.9610
# 5/5 [==============================] - 3s 5ms/step - loss: 0.0000e+00 - accuracy: 0.9582
# loss: 0.0000
# accuracy: 0.9582

# %%
# Model Summary
model.summary()
# Out:
# Model: "gradient_boosted_trees_model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
# =================================================================
# Total params: 1 (1.00 Byte)
# Trainable params: 0 (0.00 Byte)
# Non-trainable params: 1 (1.00 Byte)
# _________________________________________________________________
# Type: "GRADIENT_BOOSTED_TREES"
# Task: CLASSIFICATION
# Label: "__LABEL"
#
# Input Features (16):
# 	GrayLevelNonUniformity
# 	GrayLevelNonUniformityNormalized
# 	GrayLevelVariance
# 	HighGrayLevelZoneEmphasis
# 	LargeAreaEmphasis
# 	LargeAreaHighGrayLevelEmphasis
# 	LargeAreaLowGrayLevelEmphasis
# 	LowGrayLevelZoneEmphasis
# 	SizeZoneNonUniformity
# 	SizeZoneNonUniformityNormalized
# 	SmallAreaEmphasis
# 	SmallAreaHighGrayLevelEmphasis
# 	SmallAreaLowGrayLevelEmphasis
# 	ZoneEntropy
# 	ZonePercentage
# 	ZoneVariance
#
# Trained with weights
#
# Variable Importance: INV_MEAN_MIN_DEPTH:
#     1.        "HighGrayLevelZoneEmphasis"  0.303010 ################
#     2.   "LargeAreaHighGrayLevelEmphasis"  0.293324 ##############
#     3.           "GrayLevelNonUniformity"  0.215672 #####
#     4.    "LargeAreaLowGrayLevelEmphasis"  0.208763 ####
#     5.    "SmallAreaLowGrayLevelEmphasis"  0.205882 ####
#     6.   "SmallAreaHighGrayLevelEmphasis"  0.201253 ###
#     7.                      "ZoneEntropy"  0.191467 ##
#     8.         "LowGrayLevelZoneEmphasis"  0.190047 ##
#     9. "GrayLevelNonUniformityNormalized"  0.180093
#    10.                "GrayLevelVariance"  0.178594
#    11.                     "ZoneVariance"  0.176198
#    12.  "SizeZoneNonUniformityNormalized"  0.174483
#    13.                "LargeAreaEmphasis"  0.174062
#    14.                   "ZonePercentage"  0.173898
#    15.                "SmallAreaEmphasis"  0.172103
#    16.            "SizeZoneNonUniformity"  0.171961
#
# Variable Importance: NUM_AS_ROOT:
#     1.      "HighGrayLevelZoneEmphasis" 32.000000 ################
#     2. "LargeAreaHighGrayLevelEmphasis" 18.000000 ########
#     3.  "SmallAreaLowGrayLevelEmphasis" 11.000000 #####
#     4.  "LargeAreaLowGrayLevelEmphasis"  5.000000 ##
#     5. "SmallAreaHighGrayLevelEmphasis"  3.000000 #
#     6.         "GrayLevelNonUniformity"  1.000000
#     7.       "LowGrayLevelZoneEmphasis"  1.000000
#
# Variable Importance: NUM_NODES:
#     1.        "HighGrayLevelZoneEmphasis" 244.000000 ################
#     2.           "GrayLevelNonUniformity" 234.000000 ###############
#     3.    "LargeAreaLowGrayLevelEmphasis" 208.000000 #############
#     4.   "LargeAreaHighGrayLevelEmphasis" 203.000000 ############
#     5.   "SmallAreaHighGrayLevelEmphasis" 194.000000 ############
#     6.         "LowGrayLevelZoneEmphasis" 142.000000 ########
#     7.    "SmallAreaLowGrayLevelEmphasis" 127.000000 #######
#     8.                      "ZoneEntropy" 114.000000 ######
#     9. "GrayLevelNonUniformityNormalized" 98.000000 #####
#    10.                "GrayLevelVariance" 87.000000 ####
#    11.                     "ZoneVariance" 61.000000 ##
#    12.  "SizeZoneNonUniformityNormalized" 49.000000 #
#    13.                "LargeAreaEmphasis" 41.000000
#    14.                   "ZonePercentage" 41.000000
#    15.                "SmallAreaEmphasis" 35.000000
#    16.            "SizeZoneNonUniformity" 29.000000
#
# Variable Importance: SUM_SCORE:
#     1.        "HighGrayLevelZoneEmphasis" 18427.986846 ################
#     2.   "LargeAreaHighGrayLevelEmphasis" 3030.593184 ##
#     3.           "GrayLevelNonUniformity" 2056.845178 #
#     4.    "LargeAreaLowGrayLevelEmphasis" 1403.826112 #
#     5.    "SmallAreaLowGrayLevelEmphasis" 930.936564
#     6.   "SmallAreaHighGrayLevelEmphasis" 922.859380
#     7.         "LowGrayLevelZoneEmphasis" 636.081401
#     8. "GrayLevelNonUniformityNormalized" 465.219785
#     9.                      "ZoneEntropy" 395.910008
#    10.                "GrayLevelVariance" 288.707674
#    11.                     "ZoneVariance" 190.264543
#    12.                "LargeAreaEmphasis" 155.730023
#    13.                "SmallAreaEmphasis" 148.682976
#    14.                   "ZonePercentage" 137.793671
#    15.  "SizeZoneNonUniformityNormalized" 134.868644
#    16.            "SizeZoneNonUniformity" 115.925035
#
#
#
# Loss: BINOMIAL_LOG_LIKELIHOOD
# Validation loss value: 0.491973
# Number of trees per iteration: 1
# Node format: NOT_SET
# Number of trees: 71
# Total number of nodes: 3885
#
# Number of nodes by tree:
# Count: 71 Average: 54.7183 StdDev: 6.70754
# Min: 35 Max: 63 Ignored: 0
# ----------------------------------------------
# [ 35, 36)  1   1.41%   1.41% #
# [ 36, 37)  0   0.00%   1.41%
# [ 37, 39)  0   0.00%   1.41%
# [ 39, 40)  0   0.00%   1.41%
# [ 40, 42)  2   2.82%   4.23% #
# [ 42, 43)  0   0.00%   4.23%
# [ 43, 45)  1   1.41%   5.63% #
# [ 45, 46)  2   2.82%   8.45% #
# [ 46, 48)  9  12.68%  21.13% ######
# [ 48, 49)  0   0.00%  21.13%
# [ 49, 50)  6   8.45%  29.58% ####
# [ 50, 52)  3   4.23%  33.80% ##
# [ 52, 53)  0   0.00%  33.80%
# [ 53, 55)  6   8.45%  42.25% ####
# [ 55, 56)  6   8.45%  50.70% ####
# [ 56, 58)  6   8.45%  59.15% ####
# [ 58, 59)  0   0.00%  59.15%
# [ 59, 61)  6   8.45%  67.61% ####
# [ 61, 62) 14  19.72%  87.32% ##########
# [ 62, 63]  9  12.68% 100.00% ######
#
# Depth by leafs:
# Count: 1978 Average: 4.89535 StdDev: 0.408044
# Min: 2 Max: 5 Ignored: 0
# ----------------------------------------------
# [ 2, 3)   15   0.76%   0.76%
# [ 3, 4)   27   1.37%   2.12%
# [ 4, 5)  108   5.46%   7.58% #
# [ 5, 5] 1828  92.42% 100.00% ##########
#
# Number of training obs by leaf:
# Count: 1978 Average: 956.921 StdDev: 2527.83
# Min: 5 Max: 24779 Ignored: 0
# ----------------------------------------------
# [     5,  1243) 1659  83.87%  83.87% ##########
# [  1243,  2482)  115   5.81%  89.69% #
# [  2482,  3721)   61   3.08%  92.77%
# [  3721,  4960)   35   1.77%  94.54%
# [  4960,  6198)   25   1.26%  95.80%
# [  6198,  7437)   21   1.06%  96.87%
# [  7437,  8676)   14   0.71%  97.57%
# [  8676,  9915)    9   0.46%  98.03%
# [  9915, 11153)   10   0.51%  98.53%
# [ 11153, 12392)    3   0.15%  98.69%
# [ 12392, 13631)    3   0.15%  98.84%
# [ 13631, 14870)    8   0.40%  99.24%
# [ 14870, 16108)    3   0.15%  99.39%
# [ 16108, 17347)    4   0.20%  99.60%
# [ 17347, 18586)    2   0.10%  99.70%
# [ 18586, 19825)    1   0.05%  99.75%
# [ 19825, 21063)    0   0.00%  99.75%
# [ 21063, 22302)    0   0.00%  99.75%
# [ 22302, 23541)    2   0.10%  99.85%
# [ 23541, 24779]    3   0.15% 100.00%
#
# Attribute in nodes:
# 	244 : HighGrayLevelZoneEmphasis [NUMERICAL]
# 	234 : GrayLevelNonUniformity [NUMERICAL]
# 	208 : LargeAreaLowGrayLevelEmphasis [NUMERICAL]
# 	203 : LargeAreaHighGrayLevelEmphasis [NUMERICAL]
# 	194 : SmallAreaHighGrayLevelEmphasis [NUMERICAL]
# 	142 : LowGrayLevelZoneEmphasis [NUMERICAL]
# 	127 : SmallAreaLowGrayLevelEmphasis [NUMERICAL]
# 	114 : ZoneEntropy [NUMERICAL]
# 	98 : GrayLevelNonUniformityNormalized [NUMERICAL]
# 	87 : GrayLevelVariance [NUMERICAL]
# 	61 : ZoneVariance [NUMERICAL]
# 	49 : SizeZoneNonUniformityNormalized [NUMERICAL]
# 	41 : ZonePercentage [NUMERICAL]
# 	41 : LargeAreaEmphasis [NUMERICAL]
# 	35 : SmallAreaEmphasis [NUMERICAL]
# 	29 : SizeZoneNonUniformity [NUMERICAL]
#
# Attribute in nodes with depth <= 0:
# 	32 : HighGrayLevelZoneEmphasis [NUMERICAL]
# 	18 : LargeAreaHighGrayLevelEmphasis [NUMERICAL]
# 	11 : SmallAreaLowGrayLevelEmphasis [NUMERICAL]
# 	5 : LargeAreaLowGrayLevelEmphasis [NUMERICAL]
# 	3 : SmallAreaHighGrayLevelEmphasis [NUMERICAL]
# 	1 : LowGrayLevelZoneEmphasis [NUMERICAL]
# 	1 : GrayLevelNonUniformity [NUMERICAL]
#
# Attribute in nodes with depth <= 1:
# 	61 : LargeAreaHighGrayLevelEmphasis [NUMERICAL]
# 	56 : HighGrayLevelZoneEmphasis [NUMERICAL]
# 	19 : SmallAreaLowGrayLevelEmphasis [NUMERICAL]
# 	16 : ZoneEntropy [NUMERICAL]
# 	16 : GrayLevelNonUniformity [NUMERICAL]
# 	15 : SmallAreaHighGrayLevelEmphasis [NUMERICAL]
# 	13 : LargeAreaLowGrayLevelEmphasis [NUMERICAL]
# 	9 : LowGrayLevelZoneEmphasis [NUMERICAL]
# 	3 : ZoneVariance [NUMERICAL]
# 	2 : ZonePercentage [NUMERICAL]
# 	2 : GrayLevelNonUniformityNormalized [NUMERICAL]
# 	1 : SizeZoneNonUniformityNormalized [NUMERICAL]
#
# Attribute in nodes with depth <= 2:
# 	90 : HighGrayLevelZoneEmphasis [NUMERICAL]
# 	83 : LargeAreaHighGrayLevelEmphasis [NUMERICAL]
# 	67 : GrayLevelNonUniformity [NUMERICAL]
# 	52 : LargeAreaLowGrayLevelEmphasis [NUMERICAL]
# 	36 : SmallAreaHighGrayLevelEmphasis [NUMERICAL]
# 	34 : ZoneEntropy [NUMERICAL]
# 	32 : LowGrayLevelZoneEmphasis [NUMERICAL]
# 	31 : SmallAreaLowGrayLevelEmphasis [NUMERICAL]
# 	14 : GrayLevelVariance [NUMERICAL]
# 	14 : GrayLevelNonUniformityNormalized [NUMERICAL]
# 	9 : ZoneVariance [NUMERICAL]
# 	7 : SizeZoneNonUniformityNormalized [NUMERICAL]
# 	5 : LargeAreaEmphasis [NUMERICAL]
# 	4 : ZonePercentage [NUMERICAL]
# 	2 : SmallAreaEmphasis [NUMERICAL]
# 	2 : SizeZoneNonUniformity [NUMERICAL]
#
# Attribute in nodes with depth <= 3:
# 	158 : HighGrayLevelZoneEmphasis [NUMERICAL]
# 	128 : GrayLevelNonUniformity [NUMERICAL]
# 	122 : LargeAreaHighGrayLevelEmphasis [NUMERICAL]
# 	110 : LargeAreaLowGrayLevelEmphasis [NUMERICAL]
# 	98 : SmallAreaHighGrayLevelEmphasis [NUMERICAL]
# 	74 : LowGrayLevelZoneEmphasis [NUMERICAL]
# 	64 : ZoneEntropy [NUMERICAL]
# 	62 : SmallAreaLowGrayLevelEmphasis [NUMERICAL]
# 	44 : GrayLevelNonUniformityNormalized [NUMERICAL]
# 	35 : GrayLevelVariance [NUMERICAL]
# 	25 : SizeZoneNonUniformityNormalized [NUMERICAL]
# 	20 : LargeAreaEmphasis [NUMERICAL]
# 	17 : ZoneVariance [NUMERICAL]
# 	15 : ZonePercentage [NUMERICAL]
# 	11 : SizeZoneNonUniformity [NUMERICAL]
# 	10 : SmallAreaEmphasis [NUMERICAL]
#
# Attribute in nodes with depth <= 5:
# 	244 : HighGrayLevelZoneEmphasis [NUMERICAL]
# 	234 : GrayLevelNonUniformity [NUMERICAL]
# 	208 : LargeAreaLowGrayLevelEmphasis [NUMERICAL]
# 	203 : LargeAreaHighGrayLevelEmphasis [NUMERICAL]
# 	194 : SmallAreaHighGrayLevelEmphasis [NUMERICAL]
# 	142 : LowGrayLevelZoneEmphasis [NUMERICAL]
# 	127 : SmallAreaLowGrayLevelEmphasis [NUMERICAL]
# 	114 : ZoneEntropy [NUMERICAL]
# 	98 : GrayLevelNonUniformityNormalized [NUMERICAL]
# 	87 : GrayLevelVariance [NUMERICAL]
# 	61 : ZoneVariance [NUMERICAL]
# 	49 : SizeZoneNonUniformityNormalized [NUMERICAL]
# 	41 : ZonePercentage [NUMERICAL]
# 	41 : LargeAreaEmphasis [NUMERICAL]
# 	35 : SmallAreaEmphasis [NUMERICAL]
# 	29 : SizeZoneNonUniformity [NUMERICAL]
#
# Condition type in nodes:
# 	1907 : HigherCondition
# Condition type in nodes with depth <= 0:
# 	71 : HigherCondition
# Condition type in nodes with depth <= 1:
# 	213 : HigherCondition
# Condition type in nodes with depth <= 2:
# 	482 : HigherCondition
# Condition type in nodes with depth <= 3:
# 	993 : HigherCondition
# Condition type in nodes with depth <= 5:
# 	1907 : HigherCondition
#
# Training logs:
# Number of iteration to final model: 71
# 	Iter:1 train-loss:1.259046 valid-loss:1.266956  train-accuracy:0.889380 valid-accuracy:0.872914
# 	Iter:2 train-loss:1.154481 valid-loss:1.171713  train-accuracy:0.894182 valid-accuracy:0.866045
# 	Iter:3 train-loss:1.066716 valid-loss:1.089720  train-accuracy:0.894613 valid-accuracy:0.870225
# 	Iter:4 train-loss:0.991212 valid-loss:1.019187  train-accuracy:0.897059 valid-accuracy:0.872175
# 	Iter:5 train-loss:0.928238 valid-loss:0.959014  train-accuracy:0.896512 valid-accuracy:0.870411
# 	Iter:6 train-loss:0.873373 valid-loss:0.906181  train-accuracy:0.898070 valid-accuracy:0.872456
# 	Iter:16 train-loss:0.574730 valid-loss:0.637356  train-accuracy:0.907584 valid-accuracy:0.871250
# 	Iter:26 train-loss:0.462265 valid-loss:0.547889  train-accuracy:0.918568 valid-accuracy:0.874873
# 	Iter:36 train-loss:0.406861 valid-loss:0.513374  train-accuracy:0.924965 valid-accuracy:0.873852
# 	Iter:46 train-loss:0.376523 valid-loss:0.502134  train-accuracy:0.928193 valid-accuracy:0.879239
# 	Iter:56 train-loss:0.345888 valid-loss:0.500583  train-accuracy:0.936149 valid-accuracy:0.876732
# 	Iter:66 train-loss:0.324568 valid-loss:0.496359  train-accuracy:0.941217 valid-accuracy:0.874782
# 	Iter:76 train-loss:0.305986 valid-loss:0.495127  train-accuracy:0.945935 valid-accuracy:0.884349
# 	Iter:86 train-loss:0.293084 valid-loss:0.497046  train-accuracy:0.950833 valid-accuracy:0.884907
# 	Iter:96 train-loss:0.277748 valid-loss:0.500590  train-accuracy:0.955201 valid-accuracy:0.879244

# %%
# Model features
model.make_inspector().features()
# Out:
# ["GrayLevelNonUniformity" (1; #0),
#  "GrayLevelNonUniformityNormalized" (1; #1),
#  "GrayLevelVariance" (1; #2),
#  "HighGrayLevelZoneEmphasis" (1; #3),
#  "LargeAreaEmphasis" (1; #4),
#  "LargeAreaHighGrayLevelEmphasis" (1; #5),
#  "LargeAreaLowGrayLevelEmphasis" (1; #6),
#  "LowGrayLevelZoneEmphasis" (1; #7),
#  "SizeZoneNonUniformity" (1; #8),
#  "SizeZoneNonUniformityNormalized" (1; #9),
#  "SmallAreaEmphasis" (1; #10),
#  "SmallAreaHighGrayLevelEmphasis" (1; #11),
#  "SmallAreaLowGrayLevelEmphasis" (1; #12),
#  "ZoneEntropy" (1; #13),
#  "ZonePercentage" (1; #14),
#  "ZoneVariance" (1; #15)]

# %%
# Feature importance
model.make_inspector().variable_importances()
# Out:
# {'INV_MEAN_MIN_DEPTH': [("HighGrayLevelZoneEmphasis" (1; #3),
#    0.3030096348669285),
#   ("LargeAreaHighGrayLevelEmphasis" (1; #5), 0.2933240501243141),
#   ("GrayLevelNonUniformity" (1; #0), 0.21567217878714987),
#   ("LargeAreaLowGrayLevelEmphasis" (1; #6), 0.2087630072376949),
#   ("SmallAreaLowGrayLevelEmphasis" (1; #12), 0.20588195764652786),
#   ("SmallAreaHighGrayLevelEmphasis" (1; #11), 0.2012525272991927),
#   ("ZoneEntropy" (1; #13), 0.1914670042881206),
#   ("LowGrayLevelZoneEmphasis" (1; #7), 0.19004699645705256),
#   ("GrayLevelNonUniformityNormalized" (1; #1), 0.18009296472667963),
#   ("GrayLevelVariance" (1; #2), 0.1785937956899511),
#   ("ZoneVariance" (1; #15), 0.17619753868622834),
#   ("SizeZoneNonUniformityNormalized" (1; #9), 0.1744828343162363),
#   ("LargeAreaEmphasis" (1; #4), 0.17406161634875805),
#   ("ZonePercentage" (1; #14), 0.1738980909329215),
#   ("SmallAreaEmphasis" (1; #10), 0.17210349121503693),
#   ("SizeZoneNonUniformity" (1; #8), 0.1719608080962776)],
#  'NUM_AS_ROOT': [("HighGrayLevelZoneEmphasis" (1; #3), 32.0),
#   ("LargeAreaHighGrayLevelEmphasis" (1; #5), 18.0),
#   ("SmallAreaLowGrayLevelEmphasis" (1; #12), 11.0),
#   ("LargeAreaLowGrayLevelEmphasis" (1; #6), 5.0),
#   ("SmallAreaHighGrayLevelEmphasis" (1; #11), 3.0),
#   ("GrayLevelNonUniformity" (1; #0), 1.0),
#   ("LowGrayLevelZoneEmphasis" (1; #7), 1.0)],
#  'SUM_SCORE': [("HighGrayLevelZoneEmphasis" (1; #3), 18427.9868462049),
#   ("LargeAreaHighGrayLevelEmphasis" (1; #5), 3030.5931838797424),
#   ("GrayLevelNonUniformity" (1; #0), 2056.845177895499),
#   ("LargeAreaLowGrayLevelEmphasis" (1; #6), 1403.8261124259745),
#   ("SmallAreaLowGrayLevelEmphasis" (1; #12), 930.9365644290945),
#   ("SmallAreaHighGrayLevelEmphasis" (1; #11), 922.8593800282881),
#   ("LowGrayLevelZoneEmphasis" (1; #7), 636.0814009809761),
#   ("GrayLevelNonUniformityNormalized" (1; #1), 465.21978488188023),
#   ("ZoneEntropy" (1; #13), 395.9100075116399),
#   ("GrayLevelVariance" (1; #2), 288.7076738523027),
#   ("ZoneVariance" (1; #15), 190.2645427551173),
#   ("LargeAreaEmphasis" (1; #4), 155.73002332167152),
#   ("SmallAreaEmphasis" (1; #10), 148.68297567353622),
#   ("ZonePercentage" (1; #14), 137.79367111951726),
#   ("SizeZoneNonUniformityNormalized" (1; #9), 134.86864393340767),
#   ("SizeZoneNonUniformity" (1; #8), 115.92503483619646)],
#  'NUM_NODES': [("HighGrayLevelZoneEmphasis" (1; #3), 244.0),
#   ("GrayLevelNonUniformity" (1; #0), 234.0),
#   ("LargeAreaLowGrayLevelEmphasis" (1; #6), 208.0),
#   ("LargeAreaHighGrayLevelEmphasis" (1; #5), 203.0),
#   ("SmallAreaHighGrayLevelEmphasis" (1; #11), 194.0),
#   ("LowGrayLevelZoneEmphasis" (1; #7), 142.0),
#   ("SmallAreaLowGrayLevelEmphasis" (1; #12), 127.0),
#   ("ZoneEntropy" (1; #13), 114.0),
#   ("GrayLevelNonUniformityNormalized" (1; #1), 98.0),
#   ("GrayLevelVariance" (1; #2), 87.0),
#   ("ZoneVariance" (1; #15), 61.0),
#   ("SizeZoneNonUniformityNormalized" (1; #9), 49.0),
#   ("LargeAreaEmphasis" (1; #4), 41.0),
#   ("ZonePercentage" (1; #14), 41.0),
#   ("SmallAreaEmphasis" (1; #10), 35.0),
#   ("SizeZoneNonUniformity" (1; #8), 29.0)]}

# %%
# Model self evaluation
model.make_inspector().evaluation()
# Out:
# Evaluation(num_examples=None, accuracy=0.8780329823493958, loss=0.4919726550579071, rmse=None, ndcg=None, aucs=None, auuc=None, qini=None)

# %%
logs = model.make_inspector().training_logs()

plt.figure(figsize=(12, 4))
plt.subplot(1, 2, 1)
plt.plot([log.num_trees for log in logs], [log.evaluation.accuracy for log in logs])
plt.xlabel("Number of trees")
plt.ylabel("Accuracy (out-of-bag)")
plt.subplot(1, 2, 2)
plt.plot([log.num_trees for log in logs], [log.evaluation.loss for log in logs])
plt.xlabel("Number of trees")
plt.ylabel("Logloss (out-of-bag)")
plt.show()

# %% [markdown]
# Calculate the score of our hold-out validation dataset

# %%
predictions = model.predict(val_ds)
y_true      = validation_data["label"]

from sklearn.metrics import roc_auc_score
ROC_AUC = roc_auc_score(y_true, predictions)
print("The ROC AUC score is %.5f" % ROC_AUC )
# Out:
# 1/5 [=====>........................] - ETA: 0s
# 5/5 [==============================] - 0s 4ms/step
# The ROC AUC score is 0.99670

# %%
# Compute binary classification metrics with sklearn
import numpy as np
from sklearn.metrics import (
    accuracy_score,
    precision_score,
    recall_score,
    f1_score,
    roc_auc_score,
    average_precision_score,
    confusion_matrix,
    classification_report,
    matthews_corrcoef,
    log_loss,
    brier_score_loss,
)

# Get predictions (probabilities or class labels)
preds = model.predict(test_ds)
# If model outputs probabilities, convert to labels by threshold 0.5
if preds.ndim == 2:
    # For TFDF classification, preds may be class probabilities with shape (N, 2)
    if preds.shape[1] == 2:
        pos_probs = preds[:, 1]
    else:
        # If single-probability column (positive class)
        pos_probs = preds[:, -1]
    y_pred = (pos_probs >= 0.5).astype(int)
else:
    # Already class labels
    y_pred = preds.astype(int)
    pos_probs = None

# Ground truth labels (must be 0/1 integers)
y_true = test_data["label"].astype(int).to_numpy()

# Core metrics
metrics = {}
metrics["accuracy"] = accuracy_score(y_true, y_pred)
metrics["precision"] = precision_score(y_true, y_pred, zero_division=0)
metrics["recall"] = recall_score(y_true, y_pred, zero_division=0)
metrics["f1"] = f1_score(y_true, y_pred, zero_division=0)
metrics["mcc"] = matthews_corrcoef(y_true, y_pred)

# Probabilistic metrics (only if we have probabilities)
if pos_probs is not None:
    metrics["roc_auc"] = roc_auc_score(y_true, pos_probs)
    metrics["pr_auc"] = average_precision_score(y_true, pos_probs)
    metrics["log_loss"] = log_loss(y_true, pos_probs, labels=[0,1])
    metrics["brier_score"] = brier_score_loss(y_true, pos_probs)

# Confusion matrix and detailed report
cm = confusion_matrix(y_true, y_pred, labels=[0,1])
report = classification_report(y_true, y_pred, digits=4)

print("Sklearn binary metrics:")
for k, v in metrics.items():
    print(f"{k}: {v:.4f}")
print("\nConfusion matrix:\n", cm)
print("\nClassification report:\n", report)
# Out:
# 1/9 [==>...........................] - ETA: 0s
# 9/9 [==============================] - 0s 5ms/step
# Sklearn binary metrics:
# accuracy: 0.9569
# precision: 0.7510
# recall: 0.8471
# f1: 0.7962
# mcc: 0.7739
# roc_auc: 0.9589
# pr_auc: 0.8723
# log_loss: 0.1454
# brier_score: 0.0359
#
# Confusion matrix:
#  [[7763  248]
#  [ 135  748]]
#
# Classification report:
#                precision    recall  f1-score   support
#
#            0     0.9829    0.9690    0.9759      8011
#            1     0.7510    0.8471    0.7962       883
#
#     accuracy                         0.9569      8894
#    macro avg     0.8670    0.9081    0.8860      8894
# weighted avg     0.9599    0.9569    0.9581      8894
