# %%
# Import packages and modules
import numpy  as np
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow_decision_forests as tfdf

from sklearn.model_selection import train_test_split
# Out:
# 2026-09-10 09:46:49.253956: I tensorflow/core/util/port.cc:113] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2026-09-10 09:46:49.616134: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2026-09-10 09:46:54.593367: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
# Check the version of TensorFlow Decision Forests
print("Found TensorFlow Decision Forests v" + tfdf.__version__)
# Out:
# Found TensorFlow Decision Forests v1.9.1

# %%
datasetPath = "dataset/10p/all/kernel3/"

# %%
# Parameters
datasetPath = "dataset/10p/glrlm/kernel3/"

# %%
# train/validation/test = 70/10/20
train_data = pd.read_csv(f"{datasetPath}dataset.train.csv")
validation_data = pd.read_csv(f"{datasetPath}dataset.validation.csv")
test_data = pd.read_csv(f"{datasetPath}dataset.test.csv")

# %%
from sklearn.utils.class_weight import compute_class_weight

# tinh class weight tren tap train
classes = np.array([0, 1])
weights = compute_class_weight(class_weight="balanced", classes=classes, y=train_data["label"])
class_weight = {0: weights[0], 1: weights[1]}

# gan sample_weight cho tung dong
train_data["sample_weight"] = train_data["label"].map(class_weight)
validation_data["sample_weight"] = validation_data["label"].map(class_weight)
test_data["sample_weight"] = test_data["label"].map(class_weight)

# Convert the dataset into a TensorFlow dataset.
train_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    train_data, label="label", weight="sample_weight"
)         
val_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    validation_data, label="label", weight="sample_weight"
)
test_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    test_data, label="label", weight="sample_weight"
)
# Out:
# 2026-09-10 09:47:07.253555: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:984] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2026-09-10 09:47:07.255000: W tensorflow/core/common_runtime/gpu/gpu_device.cc:2251] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...

# %%
import keras

# %%
# %%time

# Train a Gradient Boosted Trees model.
model = tfdf.keras.GradientBoostedTreesModel()

# Add evaluation metrics
model.compile(
    metrics=["accuracy"]
)
model.fit(x=train_ds)

# # Train a Gradient Boosted Trees model.
# model = tfdf.keras.GradientBoostedTreesModel(num_trees=1500)
# model.fit(train_ds)
# Out:
# Use /tmp/tmpodbtcjo5 as temporary training directory
# Reading training dataset...
# [WARNING 26-09-10 09:47:07.3956 UTC gradient_boosted_trees.cc:1840] "goss_alpha" set but "sampling_method" not equal to "GOSS".
# [WARNING 26-09-10 09:47:07.3959 UTC gradient_boosted_trees.cc:1851] "goss_beta" set but "sampling_method" not equal to "GOSS".
# [WARNING 26-09-10 09:47:07.3959 UTC gradient_boosted_trees.cc:1865] "selective_gradient_boosting_ratio" set but "sampling_method" not equal to "SELGB".
# Training dataset read in 0:00:02.664160. Found 29597 examples.
# Training model...
# Model trained in 0:00:03.334975
# Compiling model...
# [INFO 26-09-10 09:47:13.4208 UTC kernel.cc:1233] Loading model from path /tmp/tmpodbtcjo5/model/ with prefix 3d7ea057a1bb4bb0
# [INFO 26-09-10 09:47:13.4268 UTC quick_scorer_extended.cc:911] The binary was compiled without AVX2 support, but your CPU supports it. Enable it for faster model inference.
# [INFO 26-09-10 09:47:13.4271 UTC abstract_model.cc:1362] Engine "GradientBoostedTreesQuickScorerExtended" built
# [INFO 26-09-10 09:47:13.4272 UTC kernel.cc:1061] Use fast generic engine
# Model compiled.
# CPU times: user 25.4 s, sys: 1.09 s, total: 26.5 s
# Wall time: 9.19 s

# %%
# Evaluate the model
evaluate = model.evaluate(val_ds, return_dict=True)
print()

for name, value in evaluate.items():
    print(f"{name}: {value:.4f}")
# Out:
# WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 1/5 [=====>........................] - ETA: 12s - loss: 0.0000e+00 - accuracy: 0.9710
# 5/5 [==============================] - 3s 5ms/step - loss: 0.0000e+00 - accuracy: 0.9704
# loss: 0.0000
# accuracy: 0.9704

# %%
# Model Summary
model.summary()
# Out:
# Model: "gradient_boosted_trees_model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
# =================================================================
# Total params: 1 (1.00 Byte)
# Trainable params: 0 (0.00 Byte)
# Non-trainable params: 1 (1.00 Byte)
# _________________________________________________________________
# Type: "GRADIENT_BOOSTED_TREES"
# Task: CLASSIFICATION
# Label: "__LABEL"
#
# Input Features (16):
# 	GrayLevelNonUniformity
# 	GrayLevelNonUniformityNormalized
# 	GrayLevelVariance
# 	HighGrayLevelRunEmphasis
# 	LongRunEmphasis
# 	LongRunHighGrayLevelEmphasis
# 	LongRunLowGrayLevelEmphasis
# 	LowGrayLevelRunEmphasis
# 	RunEntropy
# 	RunLengthNonUniformity
# 	RunLengthNonUniformityNormalized
# 	RunPercentage
# 	RunVariance
# 	ShortRunEmphasis
# 	ShortRunHighGrayLevelEmphasis
# 	ShortRunLowGrayLevelEmphasis
#
# Trained with weights
#
# Variable Importance: INV_MEAN_MIN_DEPTH:
#     1.     "LongRunHighGrayLevelEmphasis"  0.388259 ################
#     2.                       "RunEntropy"  0.208371 ##
#     3.      "LongRunLowGrayLevelEmphasis"  0.205235 ##
#     4.                "GrayLevelVariance"  0.203371 ##
#     5.    "ShortRunHighGrayLevelEmphasis"  0.197134 #
#     6.           "GrayLevelNonUniformity"  0.196535 #
#     7.     "ShortRunLowGrayLevelEmphasis"  0.190883 #
#     8.                      "RunVariance"  0.189383 #
#     9.          "LowGrayLevelRunEmphasis"  0.189136 #
#    10.                  "LongRunEmphasis"  0.187134
#    11.         "HighGrayLevelRunEmphasis"  0.184407
#    12. "RunLengthNonUniformityNormalized"  0.182677
#    13.           "RunLengthNonUniformity"  0.181619
#    14. "GrayLevelNonUniformityNormalized"  0.181381
#    15.                 "ShortRunEmphasis"  0.181366
#    16.                    "RunPercentage"  0.175496
#
# Variable Importance: NUM_AS_ROOT:
#     1.     "LongRunHighGrayLevelEmphasis" 65.000000 ################
#     2.      "LongRunLowGrayLevelEmphasis" 13.000000 ###
#     3.                       "RunEntropy"  6.000000 #
#     4.           "GrayLevelNonUniformity"  5.000000 #
#     5.                "GrayLevelVariance"  4.000000
#     6.          "LowGrayLevelRunEmphasis"  3.000000
#     7.           "RunLengthNonUniformity"  3.000000
#     8.                      "RunVariance"  3.000000
#     9. "RunLengthNonUniformityNormalized"  2.000000
#    10.     "ShortRunLowGrayLevelEmphasis"  2.000000
#    11.                 "ShortRunEmphasis"  1.000000
#    12.    "ShortRunHighGrayLevelEmphasis"  1.000000
#
# Variable Importance: NUM_NODES:
#     1.     "LongRunHighGrayLevelEmphasis" 465.000000 ################
#     2.                       "RunEntropy" 297.000000 #########
#     3.                "GrayLevelVariance" 234.000000 #######
#     4.      "LongRunLowGrayLevelEmphasis" 214.000000 ######
#     5.    "ShortRunHighGrayLevelEmphasis" 192.000000 #####
#     6.           "GrayLevelNonUniformity" 180.000000 #####
#     7.     "ShortRunLowGrayLevelEmphasis" 168.000000 ####
#     8.          "LowGrayLevelRunEmphasis" 147.000000 ###
#     9.                  "LongRunEmphasis" 129.000000 ###
#    10.                      "RunVariance" 126.000000 ###
#    11.         "HighGrayLevelRunEmphasis" 122.000000 ##
#    12. "GrayLevelNonUniformityNormalized" 107.000000 ##
#    13. "RunLengthNonUniformityNormalized" 70.000000
#    14.                 "ShortRunEmphasis" 70.000000
#    15.           "RunLengthNonUniformity" 63.000000
#    16.                    "RunPercentage" 46.000000
#
# Variable Importance: SUM_SCORE:
#     1.     "LongRunHighGrayLevelEmphasis" 21094.573991 ################
#     2.                       "RunEntropy" 1549.971559 #
#     3.    "ShortRunHighGrayLevelEmphasis" 1478.912812 #
#     4.                  "LongRunEmphasis" 989.053892
#     5.      "LongRunLowGrayLevelEmphasis" 800.325196
#     6.           "GrayLevelNonUniformity" 764.602699
#     7.     "ShortRunLowGrayLevelEmphasis" 565.698631
#     8.          "LowGrayLevelRunEmphasis" 493.406100
#     9.                "GrayLevelVariance" 488.298166
#    10.                      "RunVariance" 477.312633
#    11.         "HighGrayLevelRunEmphasis" 384.764198
#    12. "GrayLevelNonUniformityNormalized" 332.546563
#    13. "RunLengthNonUniformityNormalized" 239.238336
#    14.                    "RunPercentage" 195.789577
#    15.                 "ShortRunEmphasis" 179.435667
#    16.           "RunLengthNonUniformity" 139.481708
#
#
#
# Loss: BINOMIAL_LOG_LIKELIHOOD
# Validation loss value: 0.440953
# Number of trees per iteration: 1
# Node format: NOT_SET
# Number of trees: 108
# Total number of nodes: 5368
#
# Number of nodes by tree:
# Count: 108 Average: 49.7037 StdDev: 9.0239
# Min: 29 Max: 63 Ignored: 0
# ----------------------------------------------
# [ 29, 30)  1   0.93%   0.93% #
# [ 30, 32)  1   0.93%   1.85% #
# [ 32, 34)  2   1.85%   3.70% ##
# [ 34, 36)  4   3.70%   7.41% ###
# [ 36, 37)  0   0.00%   7.41%
# [ 37, 39)  4   3.70%  11.11% ###
# [ 39, 41) 12  11.11%  22.22% ##########
# [ 41, 43)  4   3.70%  25.93% ###
# [ 43, 44)  6   5.56%  31.48% #####
# [ 44, 46)  3   2.78%  34.26% ###
# [ 46, 48)  6   5.56%  39.81% #####
# [ 48, 50)  9   8.33%  48.15% ########
# [ 50, 51)  0   0.00%  48.15%
# [ 51, 53)  6   5.56%  53.70% #####
# [ 53, 55)  5   4.63%  58.33% ####
# [ 55, 57)  9   8.33%  66.67% ########
# [ 57, 58) 11  10.19%  76.85% #########
# [ 58, 60) 11  10.19%  87.04% #########
# [ 60, 62)  9   8.33%  95.37% ########
# [ 62, 63]  5   4.63% 100.00% ####
#
# Depth by leafs:
# Count: 2738 Average: 4.81702 StdDev: 0.533511
# Min: 2 Max: 5 Ignored: 0
# ----------------------------------------------
# [ 2, 3)   32   1.17%   1.17%
# [ 3, 4)   89   3.25%   4.42%
# [ 4, 5)  227   8.29%  12.71% #
# [ 5, 5] 2390  87.29% 100.00% ##########
#
# Number of training obs by leaf:
# Count: 2738 Average: 1051.56 StdDev: 2848.14
# Min: 5 Max: 23323 Ignored: 0
# ----------------------------------------------
# [     5,  1170) 2262  82.62%  82.62% ##########
# [  1170,  2336)  149   5.44%  88.06% #
# [  2336,  3502)   83   3.03%  91.09%
# [  3502,  4668)   71   2.59%  93.68%
# [  4668,  5834)   41   1.50%  95.18%
# [  5834,  7000)   29   1.06%  96.24%
# [  7000,  8166)   19   0.69%  96.93%
# [  8166,  9332)   12   0.44%  97.37%
# [  9332, 10498)   11   0.40%  97.77%
# [ 10498, 11664)    9   0.33%  98.10%
# [ 11664, 12830)    7   0.26%  98.36%
# [ 12830, 13996)    4   0.15%  98.50%
# [ 13996, 15162)    9   0.33%  98.83%
# [ 15162, 16328)    2   0.07%  98.90%
# [ 16328, 17494)    7   0.26%  99.16%
# [ 17494, 18660)    4   0.15%  99.31%
# [ 18660, 19826)    3   0.11%  99.42%
# [ 19826, 20992)    3   0.11%  99.53%
# [ 20992, 22158)    8   0.29%  99.82%
# [ 22158, 23323]    5   0.18% 100.00%
#
# Attribute in nodes:
# 	465 : LongRunHighGrayLevelEmphasis [NUMERICAL]
# 	297 : RunEntropy [NUMERICAL]
# 	234 : GrayLevelVariance [NUMERICAL]
# 	214 : LongRunLowGrayLevelEmphasis [NUMERICAL]
# 	192 : ShortRunHighGrayLevelEmphasis [NUMERICAL]
# 	180 : GrayLevelNonUniformity [NUMERICAL]
# 	168 : ShortRunLowGrayLevelEmphasis [NUMERICAL]
# 	147 : LowGrayLevelRunEmphasis [NUMERICAL]
# 	129 : LongRunEmphasis [NUMERICAL]
# 	126 : RunVariance [NUMERICAL]
# 	122 : HighGrayLevelRunEmphasis [NUMERICAL]
# 	107 : GrayLevelNonUniformityNormalized [NUMERICAL]
# 	70 : ShortRunEmphasis [NUMERICAL]
# 	70 : RunLengthNonUniformityNormalized [NUMERICAL]
# 	63 : RunLengthNonUniformity [NUMERICAL]
# 	46 : RunPercentage [NUMERICAL]
#
# Attribute in nodes with depth <= 0:
# 	65 : LongRunHighGrayLevelEmphasis [NUMERICAL]
# 	13 : LongRunLowGrayLevelEmphasis [NUMERICAL]
# 	6 : RunEntropy [NUMERICAL]
# 	5 : GrayLevelNonUniformity [NUMERICAL]
# 	4 : GrayLevelVariance [NUMERICAL]
# 	3 : RunVariance [NUMERICAL]
# 	3 : RunLengthNonUniformity [NUMERICAL]
# 	3 : LowGrayLevelRunEmphasis [NUMERICAL]
# 	2 : ShortRunLowGrayLevelEmphasis [NUMERICAL]
# 	2 : RunLengthNonUniformityNormalized [NUMERICAL]
# 	1 : ShortRunHighGrayLevelEmphasis [NUMERICAL]
# 	1 : ShortRunEmphasis [NUMERICAL]
#
# Attribute in nodes with depth <= 1:
# 	132 : LongRunHighGrayLevelEmphasis [NUMERICAL]
# 	33 : LongRunLowGrayLevelEmphasis [NUMERICAL]
# 	26 : GrayLevelVariance [NUMERICAL]
# 	22 : RunEntropy [NUMERICAL]
# 	16 : ShortRunLowGrayLevelEmphasis [NUMERICAL]
# 	15 : GrayLevelNonUniformity [NUMERICAL]
# 	14 : ShortRunHighGrayLevelEmphasis [NUMERICAL]
# 	11 : LowGrayLevelRunEmphasis [NUMERICAL]
# 	11 : LongRunEmphasis [NUMERICAL]
# 	10 : RunVariance [NUMERICAL]
# 	10 : RunLengthNonUniformity [NUMERICAL]
# 	7 : ShortRunEmphasis [NUMERICAL]
# 	7 : RunLengthNonUniformityNormalized [NUMERICAL]
# 	6 : HighGrayLevelRunEmphasis [NUMERICAL]
# 	3 : GrayLevelNonUniformityNormalized [NUMERICAL]
# 	1 : RunPercentage [NUMERICAL]
#
# Attribute in nodes with depth <= 2:
# 	184 : LongRunHighGrayLevelEmphasis [NUMERICAL]
# 	65 : ShortRunHighGrayLevelEmphasis [NUMERICAL]
# 	65 : RunEntropy [NUMERICAL]
# 	61 : LongRunLowGrayLevelEmphasis [NUMERICAL]
# 	61 : GrayLevelVariance [NUMERICAL]
# 	44 : GrayLevelNonUniformity [NUMERICAL]
# 	41 : ShortRunLowGrayLevelEmphasis [NUMERICAL]
# 	33 : LowGrayLevelRunEmphasis [NUMERICAL]
# 	32 : HighGrayLevelRunEmphasis [NUMERICAL]
# 	29 : RunVariance [NUMERICAL]
# 	29 : LongRunEmphasis [NUMERICAL]
# 	22 : ShortRunEmphasis [NUMERICAL]
# 	19 : GrayLevelNonUniformityNormalized [NUMERICAL]
# 	18 : RunLengthNonUniformityNormalized [NUMERICAL]
# 	18 : RunLengthNonUniformity [NUMERICAL]
# 	3 : RunPercentage [NUMERICAL]
#
# Attribute in nodes with depth <= 3:
# 	283 : LongRunHighGrayLevelEmphasis [NUMERICAL]
# 	159 : RunEntropy [NUMERICAL]
# 	116 : GrayLevelVariance [NUMERICAL]
# 	115 : LongRunLowGrayLevelEmphasis [NUMERICAL]
# 	109 : ShortRunHighGrayLevelEmphasis [NUMERICAL]
# 	95 : GrayLevelNonUniformity [NUMERICAL]
# 	81 : ShortRunLowGrayLevelEmphasis [NUMERICAL]
# 	79 : LowGrayLevelRunEmphasis [NUMERICAL]
# 	72 : HighGrayLevelRunEmphasis [NUMERICAL]
# 	68 : RunVariance [NUMERICAL]
# 	67 : LongRunEmphasis [NUMERICAL]
# 	60 : GrayLevelNonUniformityNormalized [NUMERICAL]
# 	42 : ShortRunEmphasis [NUMERICAL]
# 	36 : RunLengthNonUniformityNormalized [NUMERICAL]
# 	32 : RunLengthNonUniformity [NUMERICAL]
# 	21 : RunPercentage [NUMERICAL]
#
# Attribute in nodes with depth <= 5:
# 	465 : LongRunHighGrayLevelEmphasis [NUMERICAL]
# 	297 : RunEntropy [NUMERICAL]
# 	234 : GrayLevelVariance [NUMERICAL]
# 	214 : LongRunLowGrayLevelEmphasis [NUMERICAL]
# 	192 : ShortRunHighGrayLevelEmphasis [NUMERICAL]
# 	180 : GrayLevelNonUniformity [NUMERICAL]
# 	168 : ShortRunLowGrayLevelEmphasis [NUMERICAL]
# 	147 : LowGrayLevelRunEmphasis [NUMERICAL]
# 	129 : LongRunEmphasis [NUMERICAL]
# 	126 : RunVariance [NUMERICAL]
# 	122 : HighGrayLevelRunEmphasis [NUMERICAL]
# 	107 : GrayLevelNonUniformityNormalized [NUMERICAL]
# 	70 : ShortRunEmphasis [NUMERICAL]
# 	70 : RunLengthNonUniformityNormalized [NUMERICAL]
# 	63 : RunLengthNonUniformity [NUMERICAL]
# 	46 : RunPercentage [NUMERICAL]
#
# Condition type in nodes:
# 	2630 : HigherCondition
# Condition type in nodes with depth <= 0:
# 	108 : HigherCondition
# Condition type in nodes with depth <= 1:
# 	324 : HigherCondition
# Condition type in nodes with depth <= 2:
# 	724 : HigherCondition
# Condition type in nodes with depth <= 3:
# 	1435 : HigherCondition
# Condition type in nodes with depth <= 5:
# 	2630 : HigherCondition
#
# Training logs:
# Number of iteration to final model: 108
# 	Iter:1 train-loss:1.259884 valid-loss:1.263274  train-accuracy:0.882352 valid-accuracy:0.866894
# 	Iter:2 train-loss:1.156222 valid-loss:1.164169  train-accuracy:0.885487 valid-accuracy:0.879495
# 	Iter:3 train-loss:1.068585 valid-loss:1.079407  train-accuracy:0.886415 valid-accuracy:0.877817
# 	Iter:4 train-loss:0.993276 valid-loss:1.008175  train-accuracy:0.898317 valid-accuracy:0.892335
# 	Iter:5 train-loss:0.928828 valid-loss:0.945252  train-accuracy:0.898336 valid-accuracy:0.895685
# 	Iter:6 train-loss:0.872390 valid-loss:0.890628  train-accuracy:0.900408 valid-accuracy:0.901276
# 	Iter:16 train-loss:0.569361 valid-loss:0.603067  train-accuracy:0.913467 valid-accuracy:0.905840
# 	Iter:26 train-loss:0.466243 valid-loss:0.524049  train-accuracy:0.918532 valid-accuracy:0.908167
# 	Iter:36 train-loss:0.411739 valid-loss:0.483206  train-accuracy:0.922977 valid-accuracy:0.909377
# 	Iter:46 train-loss:0.376517 valid-loss:0.468200  train-accuracy:0.929232 valid-accuracy:0.911240
# 	Iter:56 train-loss:0.351252 valid-loss:0.457829  train-accuracy:0.935747 valid-accuracy:0.911799
# 	Iter:66 train-loss:0.331303 valid-loss:0.452323  train-accuracy:0.937506 valid-accuracy:0.901372
# 	Iter:76 train-loss:0.315357 valid-loss:0.445207  train-accuracy:0.943771 valid-accuracy:0.901931
# 	Iter:86 train-loss:0.299584 valid-loss:0.442770  train-accuracy:0.948527 valid-accuracy:0.899976
# 	Iter:96 train-loss:0.287958 valid-loss:0.444780  train-accuracy:0.951594 valid-accuracy:0.896904
# 	Iter:106 train-loss:0.275636 valid-loss:0.441402  train-accuracy:0.953993 valid-accuracy:0.897276
# 	Iter:116 train-loss:0.266000 valid-loss:0.443934  train-accuracy:0.955851 valid-accuracy:0.897649
# 	Iter:126 train-loss:0.257083 valid-loss:0.443669  train-accuracy:0.959749 valid-accuracy:0.899140
# 	Iter:136 train-loss:0.249256 valid-loss:0.446393  train-accuracy:0.961467 valid-accuracy:0.899699

# %%
# Model features
model.make_inspector().features()
# Out:
# ["GrayLevelNonUniformity" (1; #0),
#  "GrayLevelNonUniformityNormalized" (1; #1),
#  "GrayLevelVariance" (1; #2),
#  "HighGrayLevelRunEmphasis" (1; #3),
#  "LongRunEmphasis" (1; #4),
#  "LongRunHighGrayLevelEmphasis" (1; #5),
#  "LongRunLowGrayLevelEmphasis" (1; #6),
#  "LowGrayLevelRunEmphasis" (1; #7),
#  "RunEntropy" (1; #8),
#  "RunLengthNonUniformity" (1; #9),
#  "RunLengthNonUniformityNormalized" (1; #10),
#  "RunPercentage" (1; #11),
#  "RunVariance" (1; #12),
#  "ShortRunEmphasis" (1; #13),
#  "ShortRunHighGrayLevelEmphasis" (1; #14),
#  "ShortRunLowGrayLevelEmphasis" (1; #15)]

# %%
# Feature importance
model.make_inspector().variable_importances()
# Out:
# {'INV_MEAN_MIN_DEPTH': [("LongRunHighGrayLevelEmphasis" (1; #5),
#    0.3882585578765678),
#   ("RunEntropy" (1; #8), 0.20837092029363397),
#   ("LongRunLowGrayLevelEmphasis" (1; #6), 0.2052352984400694),
#   ("GrayLevelVariance" (1; #2), 0.2033708370857389),
#   ("ShortRunHighGrayLevelEmphasis" (1; #14), 0.19713405595539163),
#   ("GrayLevelNonUniformity" (1; #0), 0.19653505191384388),
#   ("ShortRunLowGrayLevelEmphasis" (1; #15), 0.19088336968451688),
#   ("RunVariance" (1; #12), 0.18938336460548472),
#   ("LowGrayLevelRunEmphasis" (1; #7), 0.18913634683162797),
#   ("LongRunEmphasis" (1; #4), 0.1871342810846312),
#   ("HighGrayLevelRunEmphasis" (1; #3), 0.1844074432675834),
#   ("RunLengthNonUniformityNormalized" (1; #10), 0.18267693728728174),
#   ("RunLengthNonUniformity" (1; #9), 0.1816194239256163),
#   ("GrayLevelNonUniformityNormalized" (1; #1), 0.18138050636693254),
#   ("ShortRunEmphasis" (1; #13), 0.18136624855187178),
#   ("RunPercentage" (1; #11), 0.17549571999114086)],
#  'SUM_SCORE': [("LongRunHighGrayLevelEmphasis" (1; #5), 21094.573991421003),
#   ("RunEntropy" (1; #8), 1549.9715592526572),
#   ("ShortRunHighGrayLevelEmphasis" (1; #14), 1478.9128119293432),
#   ("LongRunEmphasis" (1; #4), 989.0538921614813),
#   ("LongRunLowGrayLevelEmphasis" (1; #6), 800.3251957848844),
#   ("GrayLevelNonUniformity" (1; #0), 764.6026991590213),
#   ("ShortRunLowGrayLevelEmphasis" (1; #15), 565.698630691134),
#   ("LowGrayLevelRunEmphasis" (1; #7), 493.40609989891215),
#   ("GrayLevelVariance" (1; #2), 488.29816619919643),
#   ("RunVariance" (1; #12), 477.3126328413719),
#   ("HighGrayLevelRunEmphasis" (1; #3), 384.76419767244255),
#   ("GrayLevelNonUniformityNormalized" (1; #1), 332.54656251375485),
#   ("RunLengthNonUniformityNormalized" (1; #10), 239.23833619727662),
#   ("RunPercentage" (1; #11), 195.78957681884992),
#   ("ShortRunEmphasis" (1; #13), 179.43566684889694),
#   ("RunLengthNonUniformity" (1; #9), 139.48170830007703)],
#  'NUM_AS_ROOT': [("LongRunHighGrayLevelEmphasis" (1; #5), 65.0),
#   ("LongRunLowGrayLevelEmphasis" (1; #6), 13.0),
#   ("RunEntropy" (1; #8), 6.0),
#   ("GrayLevelNonUniformity" (1; #0), 5.0),
#   ("GrayLevelVariance" (1; #2), 4.0),
#   ("LowGrayLevelRunEmphasis" (1; #7), 3.0),
#   ("RunLengthNonUniformity" (1; #9), 3.0),
#   ("RunVariance" (1; #12), 3.0),
#   ("RunLengthNonUniformityNormalized" (1; #10), 2.0),
#   ("ShortRunLowGrayLevelEmphasis" (1; #15), 2.0),
#   ("ShortRunEmphasis" (1; #13), 1.0),
#   ("ShortRunHighGrayLevelEmphasis" (1; #14), 1.0)],
#  'NUM_NODES': [("LongRunHighGrayLevelEmphasis" (1; #5), 465.0),
#   ("RunEntropy" (1; #8), 297.0),
#   ("GrayLevelVariance" (1; #2), 234.0),
#   ("LongRunLowGrayLevelEmphasis" (1; #6), 214.0),
#   ("ShortRunHighGrayLevelEmphasis" (1; #14), 192.0),
#   ("GrayLevelNonUniformity" (1; #0), 180.0),
#   ("ShortRunLowGrayLevelEmphasis" (1; #15), 168.0),
#   ("LowGrayLevelRunEmphasis" (1; #7), 147.0),
#   ("LongRunEmphasis" (1; #4), 129.0),
#   ("RunVariance" (1; #12), 126.0),
#   ("HighGrayLevelRunEmphasis" (1; #3), 122.0),
#   ("GrayLevelNonUniformityNormalized" (1; #1), 107.0),
#   ("RunLengthNonUniformityNormalized" (1; #10), 70.0),
#   ("ShortRunEmphasis" (1; #13), 70.0),
#   ("RunLengthNonUniformity" (1; #9), 63.0),
#   ("RunPercentage" (1; #11), 46.0)]}

# %%
# Model self evaluation
model.make_inspector().evaluation()
# Out:
# Evaluation(num_examples=None, accuracy=0.8972764611244202, loss=0.4409528970718384, rmse=None, ndcg=None, aucs=None, auuc=None, qini=None)

# %%
logs = model.make_inspector().training_logs()

plt.figure(figsize=(12, 4))
plt.subplot(1, 2, 1)
plt.plot([log.num_trees for log in logs], [log.evaluation.accuracy for log in logs])
plt.xlabel("Number of trees")
plt.ylabel("Accuracy (out-of-bag)")
plt.subplot(1, 2, 2)
plt.plot([log.num_trees for log in logs], [log.evaluation.loss for log in logs])
plt.xlabel("Number of trees")
plt.ylabel("Logloss (out-of-bag)")
plt.show()

# %% [markdown]
# Calculate the score of our hold-out validation dataset

# %%
predictions = model.predict(val_ds)
y_true      = validation_data["label"]

from sklearn.metrics import roc_auc_score
ROC_AUC = roc_auc_score(y_true, predictions)
print("The ROC AUC score is %.5f" % ROC_AUC )
# Out:
# 1/5 [=====>........................] - ETA: 0s
# 5/5 [==============================] - 0s 4ms/step
# The ROC AUC score is 0.99617

# %%
# Compute binary classification metrics with sklearn
import numpy as np
from sklearn.metrics import (
    accuracy_score,
    precision_score,
    recall_score,
    f1_score,
    roc_auc_score,
    average_precision_score,
    confusion_matrix,
    classification_report,
    matthews_corrcoef,
    log_loss,
    brier_score_loss,
)

# Get predictions (probabilities or class labels)
preds = model.predict(test_ds)
# If model outputs probabilities, convert to labels by threshold 0.5
if preds.ndim == 2:
    # For TFDF classification, preds may be class probabilities with shape (N, 2)
    if preds.shape[1] == 2:
        pos_probs = preds[:, 1]
    else:
        # If single-probability column (positive class)
        pos_probs = preds[:, -1]
    y_pred = (pos_probs >= 0.5).astype(int)
else:
    # Already class labels
    y_pred = preds.astype(int)
    pos_probs = None

# Ground truth labels (must be 0/1 integers)
y_true = test_data["label"].astype(int).to_numpy()

# Core metrics
metrics = {}
metrics["accuracy"] = accuracy_score(y_true, y_pred)
metrics["precision"] = precision_score(y_true, y_pred, zero_division=0)
metrics["recall"] = recall_score(y_true, y_pred, zero_division=0)
metrics["f1"] = f1_score(y_true, y_pred, zero_division=0)
metrics["mcc"] = matthews_corrcoef(y_true, y_pred)

# Probabilistic metrics (only if we have probabilities)
if pos_probs is not None:
    metrics["roc_auc"] = roc_auc_score(y_true, pos_probs)
    metrics["pr_auc"] = average_precision_score(y_true, pos_probs)
    metrics["log_loss"] = log_loss(y_true, pos_probs, labels=[0,1])
    metrics["brier_score"] = brier_score_loss(y_true, pos_probs)

# Confusion matrix and detailed report
cm = confusion_matrix(y_true, y_pred, labels=[0,1])
report = classification_report(y_true, y_pred, digits=4)

print("Sklearn binary metrics:")
for k, v in metrics.items():
    print(f"{k}: {v:.4f}")
print("\nConfusion matrix:\n", cm)
print("\nClassification report:\n", report)
# Out:
# 1/9 [==>...........................] - ETA: 0s
# 9/9 [==============================] - 0s 4ms/step
# Sklearn binary metrics:
# accuracy: 0.9630
# precision: 0.8057
# recall: 0.8267
# f1: 0.8161
# mcc: 0.7956
# roc_auc: 0.9615
# pr_auc: 0.8777
# log_loss: 0.1253
# brier_score: 0.0301
#
# Confusion matrix:
#  [[7835  176]
#  [ 153  730]]
#
# Classification report:
#                precision    recall  f1-score   support
#
#            0     0.9808    0.9780    0.9794      8011
#            1     0.8057    0.8267    0.8161       883
#
#     accuracy                         0.9630      8894
#    macro avg     0.8933    0.9024    0.8978      8894
# weighted avg     0.9635    0.9630    0.9632      8894
