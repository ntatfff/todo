# %%
# Import packages and modules
import numpy  as np
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow_decision_forests as tfdf

from sklearn.model_selection import train_test_split
# Out:
# 2026-09-10 09:44:53.482284: I tensorflow/core/util/port.cc:113] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2026-09-10 09:44:53.846119: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2026-09-10 09:44:58.610650: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
# Check the version of TensorFlow Decision Forests
print("Found TensorFlow Decision Forests v" + tfdf.__version__)
# Out:
# Found TensorFlow Decision Forests v1.9.1

# %%
datasetPath = "dataset/10p/all/kernel3/"

# %%
# Parameters
datasetPath = "dataset/10p/firstorder/kernel3/"

# %%
# train/validation/test = 70/10/20
train_data = pd.read_csv(f"{datasetPath}dataset.train.csv")
validation_data = pd.read_csv(f"{datasetPath}dataset.validation.csv")
test_data = pd.read_csv(f"{datasetPath}dataset.test.csv")

# %%
from sklearn.utils.class_weight import compute_class_weight

# tinh class weight tren tap train
classes = np.array([0, 1])
weights = compute_class_weight(class_weight="balanced", classes=classes, y=train_data["label"])
class_weight = {0: weights[0], 1: weights[1]}

# gan sample_weight cho tung dong
train_data["sample_weight"] = train_data["label"].map(class_weight)
validation_data["sample_weight"] = validation_data["label"].map(class_weight)
test_data["sample_weight"] = test_data["label"].map(class_weight)

# Convert the dataset into a TensorFlow dataset.
train_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    train_data, label="label", weight="sample_weight"
)         
val_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    validation_data, label="label", weight="sample_weight"
)
test_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    test_data, label="label", weight="sample_weight"
)
# Out:
# 2026-09-10 09:45:11.239690: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:984] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2026-09-10 09:45:11.241360: W tensorflow/core/common_runtime/gpu/gpu_device.cc:2251] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...

# %%
import keras

# %%
# %%time

# Train a Gradient Boosted Trees model.
model = tfdf.keras.GradientBoostedTreesModel()

# Add evaluation metrics
model.compile(
    metrics=["accuracy"]
)
model.fit(x=train_ds)

# # Train a Gradient Boosted Trees model.
# model = tfdf.keras.GradientBoostedTreesModel(num_trees=1500)
# model.fit(train_ds)
# Out:
# Use /tmp/tmpgnpq0xu0 as temporary training directory
# Reading training dataset...
# [WARNING 26-09-10 09:45:11.3926 UTC gradient_boosted_trees.cc:1840] "goss_alpha" set but "sampling_method" not equal to "GOSS".
# [WARNING 26-09-10 09:45:11.3928 UTC gradient_boosted_trees.cc:1851] "goss_beta" set but "sampling_method" not equal to "GOSS".
# [WARNING 26-09-10 09:45:11.3928 UTC gradient_boosted_trees.cc:1865] "selective_gradient_boosting_ratio" set but "sampling_method" not equal to "SELGB".
# Training dataset read in 0:00:02.818648. Found 29597 examples.
# Training model...
# Model trained in 0:00:02.386268
# Compiling model...
# [INFO 26-09-10 09:45:16.6257 UTC kernel.cc:1233] Loading model from path /tmp/tmpgnpq0xu0/model/ with prefix 1f96efd7b47b486f
# [INFO 26-09-10 09:45:16.6301 UTC quick_scorer_extended.cc:911] The binary was compiled without AVX2 support, but your CPU supports it. Enable it for faster model inference.
# [INFO 26-09-10 09:45:16.6303 UTC abstract_model.cc:1362] Engine "GradientBoostedTreesQuickScorerExtended" built
# [INFO 26-09-10 09:45:16.6303 UTC kernel.cc:1061] Use fast generic engine
# Model compiled.
# CPU times: user 20.6 s, sys: 834 ms, total: 21.4 s
# Wall time: 8.39 s

# %%
# Evaluate the model
evaluate = model.evaluate(val_ds, return_dict=True)
print()

for name, value in evaluate.items():
    print(f"{name}: {value:.4f}")
# Out:
# WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 1/5 [=====>........................] - ETA: 14s - loss: 0.0000e+00 - accuracy: 0.9320
# 5/5 [==============================] - 4s 5ms/step - loss: 0.0000e+00 - accuracy: 0.9402
# loss: 0.0000
# accuracy: 0.9402

# %%
# Model Summary
model.summary()
# Out:
# Model: "gradient_boosted_trees_model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
# =================================================================
# Total params: 1 (1.00 Byte)
# Trainable params: 0 (0.00 Byte)
# Non-trainable params: 1 (1.00 Byte)
# _________________________________________________________________
# Type: "GRADIENT_BOOSTED_TREES"
# Task: CLASSIFICATION
# Label: "__LABEL"
#
# Input Features (18):
# 	10Percentile
# 	90Percentile
# 	Energy
# 	Entropy
# 	InterquartileRange
# 	Kurtosis
# 	Maximum
# 	Mean
# 	MeanAbsoluteDeviation
# 	Median
# 	Minimum
# 	Range
# 	RobustMeanAbsoluteDeviation
# 	RootMeanSquared
# 	Skewness
# 	TotalEnergy
# 	Uniformity
# 	Variance
#
# Trained with weights
#
# Variable Importance: INV_MEAN_MIN_DEPTH:
#     1.                      "Median"  0.257387 ################
#     2.                "90Percentile"  0.242728 #############
#     3.                     "Maximum"  0.236631 ############
#     4.                     "Minimum"  0.211106 #######
#     5.                    "Skewness"  0.204531 ######
#     6.                        "Mean"  0.200268 #####
#     7.                "10Percentile"  0.199543 #####
#     8.                 "TotalEnergy"  0.191512 ###
#     9.                  "Uniformity"  0.190653 ###
#    10.             "RootMeanSquared"  0.188835 ###
#    11.                       "Range"  0.182723 ##
#    12.                      "Energy"  0.182280 #
#    13.                     "Entropy"  0.177722 #
#    14.                    "Kurtosis"  0.177267
#    15.                    "Variance"  0.175905
#    16. "RobustMeanAbsoluteDeviation"  0.175187
#    17.          "InterquartileRange"  0.174368
#    18.       "MeanAbsoluteDeviation"  0.172011
#
# Variable Importance: NUM_AS_ROOT:
#     1.          "Median" 14.000000 ################
#     2.    "90Percentile" 13.000000 ##############
#     3.         "Maximum"  8.000000 #######
#     4.         "Minimum"  7.000000 #####
#     5.            "Mean"  5.000000 ##
#     6. "RootMeanSquared"  5.000000 ##
#     7.     "TotalEnergy"  5.000000 ##
#     8.    "10Percentile"  3.000000
#     9.          "Energy"  3.000000
#    10.        "Skewness"  3.000000
#
# Variable Importance: NUM_NODES:
#     1.                     "Maximum" 225.000000 ################
#     2.                      "Median" 217.000000 ###############
#     3.                    "Skewness" 180.000000 ############
#     4.                "90Percentile" 173.000000 ###########
#     5.                "10Percentile" 133.000000 ########
#     6.                       "Range" 109.000000 ######
#     7.                  "Uniformity" 103.000000 ######
#     8.                     "Minimum" 101.000000 ######
#     9.                        "Mean" 98.000000 #####
#    10.                    "Kurtosis" 79.000000 ####
#    11.                     "Entropy" 60.000000 ##
#    12.                    "Variance" 57.000000 ##
#    13.          "InterquartileRange" 55.000000 ##
#    14.                 "TotalEnergy" 45.000000 #
#    15.             "RootMeanSquared" 40.000000 #
#    16.                      "Energy" 32.000000
#    17. "RobustMeanAbsoluteDeviation" 28.000000
#    18.       "MeanAbsoluteDeviation" 22.000000
#
# Variable Importance: SUM_SCORE:
#     1.                "90Percentile" 8970.335976 ################
#     2.                 "TotalEnergy" 4652.313049 ########
#     3.             "RootMeanSquared" 2358.653251 ####
#     4.                     "Maximum" 2038.750007 ###
#     5.                  "Uniformity" 1694.981666 ##
#     6.                        "Mean" 1611.833697 ##
#     7.                "10Percentile" 1519.708317 ##
#     8.                      "Median" 1507.451883 ##
#     9.                    "Skewness" 898.661506 #
#    10.                      "Energy" 557.755544
#    11.                     "Minimum" 529.840306
#    12.                     "Entropy" 468.178747
#    13.                       "Range" 438.456799
#    14.                    "Kurtosis" 274.780298
#    15.                    "Variance" 215.129102
#    16.          "InterquartileRange" 203.174940
#    17. "RobustMeanAbsoluteDeviation" 90.954024
#    18.       "MeanAbsoluteDeviation" 66.961203
#
#
#
# Loss: BINOMIAL_LOG_LIKELIHOOD
# Validation loss value: 0.543098
# Number of trees per iteration: 1
# Node format: NOT_SET
# Number of trees: 66
# Total number of nodes: 3580
#
# Number of nodes by tree:
# Count: 66 Average: 54.2424 StdDev: 7.09046
# Min: 37 Max: 63 Ignored: 0
# ----------------------------------------------
# [ 37, 38)  2   3.03%   3.03% ##
# [ 38, 39)  0   0.00%   3.03%
# [ 39, 41)  1   1.52%   4.55% #
# [ 41, 42)  1   1.52%   6.06% #
# [ 42, 43)  0   0.00%   6.06%
# [ 43, 45)  3   4.55%  10.61% ###
# [ 45, 46)  1   1.52%  12.12% #
# [ 46, 47)  0   0.00%  12.12%
# [ 47, 49)  7  10.61%  22.73% ######
# [ 49, 50)  5   7.58%  30.30% #####
# [ 50, 51)  0   0.00%  30.30%
# [ 51, 53)  3   4.55%  34.85% ###
# [ 53, 54)  3   4.55%  39.39% ###
# [ 54, 55)  0   0.00%  39.39%
# [ 55, 57)  7  10.61%  50.00% ######
# [ 57, 58) 10  15.15%  65.15% #########
# [ 58, 59)  0   0.00%  65.15%
# [ 59, 61)  7  10.61%  75.76% ######
# [ 61, 62)  5   7.58%  83.33% #####
# [ 62, 63] 11  16.67% 100.00% ##########
#
# Depth by leafs:
# Count: 1823 Average: 4.87932 StdDev: 0.414659
# Min: 2 Max: 5 Ignored: 0
# ----------------------------------------------
# [ 2, 3)    9   0.49%   0.49%
# [ 3, 4)   33   1.81%   2.30%
# [ 4, 5)  127   6.97%   9.27% #
# [ 5, 5] 1654  90.73% 100.00% ##########
#
# Number of training obs by leaf:
# Count: 1823 Average: 965.164 StdDev: 2582.52
# Min: 5 Max: 22406 Ignored: 0
# ----------------------------------------------
# [     5,  1125) 1530  83.93%  83.93% ##########
# [  1125,  2245)   87   4.77%  88.70% #
# [  2245,  3365)   53   2.91%  91.61%
# [  3365,  4485)   37   2.03%  93.64%
# [  4485,  5605)   23   1.26%  94.90%
# [  5605,  6725)   19   1.04%  95.94%
# [  6725,  7845)   16   0.88%  96.82%
# [  7845,  8965)   12   0.66%  97.48%
# [  8965, 10085)    7   0.38%  97.86%
# [ 10085, 11206)    6   0.33%  98.19%
# [ 11206, 12326)    4   0.22%  98.41%
# [ 12326, 13446)    7   0.38%  98.79%
# [ 13446, 14566)    3   0.16%  98.96%
# [ 14566, 15686)    4   0.22%  99.18%
# [ 15686, 16806)    3   0.16%  99.34%
# [ 16806, 17926)    5   0.27%  99.62%
# [ 17926, 19046)    3   0.16%  99.78%
# [ 19046, 20166)    1   0.05%  99.84%
# [ 20166, 21286)    2   0.11%  99.95%
# [ 21286, 22406]    1   0.05% 100.00%
#
# Attribute in nodes:
# 	225 : Maximum [NUMERICAL]
# 	217 : Median [NUMERICAL]
# 	180 : Skewness [NUMERICAL]
# 	173 : 90Percentile [NUMERICAL]
# 	133 : 10Percentile [NUMERICAL]
# 	109 : Range [NUMERICAL]
# 	103 : Uniformity [NUMERICAL]
# 	101 : Minimum [NUMERICAL]
# 	98 : Mean [NUMERICAL]
# 	79 : Kurtosis [NUMERICAL]
# 	60 : Entropy [NUMERICAL]
# 	57 : Variance [NUMERICAL]
# 	55 : InterquartileRange [NUMERICAL]
# 	45 : TotalEnergy [NUMERICAL]
# 	40 : RootMeanSquared [NUMERICAL]
# 	32 : Energy [NUMERICAL]
# 	28 : RobustMeanAbsoluteDeviation [NUMERICAL]
# 	22 : MeanAbsoluteDeviation [NUMERICAL]
#
# Attribute in nodes with depth <= 0:
# 	14 : Median [NUMERICAL]
# 	13 : 90Percentile [NUMERICAL]
# 	8 : Maximum [NUMERICAL]
# 	7 : Minimum [NUMERICAL]
# 	5 : TotalEnergy [NUMERICAL]
# 	5 : RootMeanSquared [NUMERICAL]
# 	5 : Mean [NUMERICAL]
# 	3 : Skewness [NUMERICAL]
# 	3 : Energy [NUMERICAL]
# 	3 : 10Percentile [NUMERICAL]
#
# Attribute in nodes with depth <= 1:
# 	37 : Median [NUMERICAL]
# 	25 : Maximum [NUMERICAL]
# 	24 : Minimum [NUMERICAL]
# 	24 : 90Percentile [NUMERICAL]
# 	17 : Mean [NUMERICAL]
# 	17 : 10Percentile [NUMERICAL]
# 	14 : Skewness [NUMERICAL]
# 	12 : TotalEnergy [NUMERICAL]
# 	8 : RootMeanSquared [NUMERICAL]
# 	6 : Uniformity [NUMERICAL]
# 	6 : Energy [NUMERICAL]
# 	3 : Range [NUMERICAL]
# 	2 : RobustMeanAbsoluteDeviation [NUMERICAL]
# 	2 : Entropy [NUMERICAL]
# 	1 : Variance [NUMERICAL]
#
# Attribute in nodes with depth <= 2:
# 	69 : Maximum [NUMERICAL]
# 	66 : Median [NUMERICAL]
# 	55 : 90Percentile [NUMERICAL]
# 	45 : Skewness [NUMERICAL]
# 	35 : Minimum [NUMERICAL]
# 	31 : 10Percentile [NUMERICAL]
# 	28 : Mean [NUMERICAL]
# 	27 : Uniformity [NUMERICAL]
# 	18 : RootMeanSquared [NUMERICAL]
# 	17 : TotalEnergy [NUMERICAL]
# 	15 : Range [NUMERICAL]
# 	11 : Kurtosis [NUMERICAL]
# 	10 : Entropy [NUMERICAL]
# 	9 : Energy [NUMERICAL]
# 	6 : Variance [NUMERICAL]
# 	5 : RobustMeanAbsoluteDeviation [NUMERICAL]
# 	5 : InterquartileRange [NUMERICAL]
# 	1 : MeanAbsoluteDeviation [NUMERICAL]
#
# Attribute in nodes with depth <= 3:
# 	129 : Median [NUMERICAL]
# 	128 : Maximum [NUMERICAL]
# 	105 : 90Percentile [NUMERICAL]
# 	99 : Skewness [NUMERICAL]
# 	62 : Uniformity [NUMERICAL]
# 	62 : 10Percentile [NUMERICAL]
# 	59 : Minimum [NUMERICAL]
# 	52 : Mean [NUMERICAL]
# 	42 : Range [NUMERICAL]
# 	33 : Kurtosis [NUMERICAL]
# 	31 : TotalEnergy [NUMERICAL]
# 	26 : Entropy [NUMERICAL]
# 	23 : InterquartileRange [NUMERICAL]
# 	22 : RootMeanSquared [NUMERICAL]
# 	18 : Variance [NUMERICAL]
# 	18 : Energy [NUMERICAL]
# 	13 : RobustMeanAbsoluteDeviation [NUMERICAL]
# 	8 : MeanAbsoluteDeviation [NUMERICAL]
#
# Attribute in nodes with depth <= 5:
# 	225 : Maximum [NUMERICAL]
# 	217 : Median [NUMERICAL]
# 	180 : Skewness [NUMERICAL]
# 	173 : 90Percentile [NUMERICAL]
# 	133 : 10Percentile [NUMERICAL]
# 	109 : Range [NUMERICAL]
# 	103 : Uniformity [NUMERICAL]
# 	101 : Minimum [NUMERICAL]
# 	98 : Mean [NUMERICAL]
# 	79 : Kurtosis [NUMERICAL]
# 	60 : Entropy [NUMERICAL]
# 	57 : Variance [NUMERICAL]
# 	55 : InterquartileRange [NUMERICAL]
# 	45 : TotalEnergy [NUMERICAL]
# 	40 : RootMeanSquared [NUMERICAL]
# 	32 : Energy [NUMERICAL]
# 	28 : RobustMeanAbsoluteDeviation [NUMERICAL]
# 	22 : MeanAbsoluteDeviation [NUMERICAL]
#
# Condition type in nodes:
# 	1757 : HigherCondition
# Condition type in nodes with depth <= 0:
# 	66 : HigherCondition
# Condition type in nodes with depth <= 1:
# 	198 : HigherCondition
# Condition type in nodes with depth <= 2:
# 	453 : HigherCondition
# Condition type in nodes with depth <= 3:
# 	930 : HigherCondition
# Condition type in nodes with depth <= 5:
# 	1757 : HigherCondition
#
# Training logs:
# Number of iteration to final model: 66
# 	Iter:1 train-loss:1.266322 valid-loss:1.268387  train-accuracy:0.878922 valid-accuracy:0.875989
# 	Iter:2 train-loss:1.168491 valid-loss:1.174903  train-accuracy:0.878984 valid-accuracy:0.857109
# 	Iter:3 train-loss:1.081828 valid-loss:1.091213  train-accuracy:0.885049 valid-accuracy:0.869183
# 	Iter:4 train-loss:1.011880 valid-loss:1.023407  train-accuracy:0.888566 valid-accuracy:0.876268
# 	Iter:5 train-loss:0.948703 valid-loss:0.964446  train-accuracy:0.887534 valid-accuracy:0.872907
# 	Iter:6 train-loss:0.896777 valid-loss:0.915554  train-accuracy:0.887363 valid-accuracy:0.875541
# 	Iter:16 train-loss:0.610886 valid-loss:0.662731  train-accuracy:0.897705 valid-accuracy:0.877998
# 	Iter:26 train-loss:0.506347 valid-loss:0.585348  train-accuracy:0.908064 valid-accuracy:0.886444
# 	Iter:36 train-loss:0.451984 valid-loss:0.562759  train-accuracy:0.914406 valid-accuracy:0.888808
# 	Iter:46 train-loss:0.421849 valid-loss:0.548809  train-accuracy:0.918535 valid-accuracy:0.892532
# 	Iter:56 train-loss:0.399846 valid-loss:0.545719  train-accuracy:0.923605 valid-accuracy:0.887628
# 	Iter:66 train-loss:0.377728 valid-loss:0.543098  train-accuracy:0.929726 valid-accuracy:0.896257
# 	Iter:76 train-loss:0.355444 valid-loss:0.544828  train-accuracy:0.933484 valid-accuracy:0.897166
# 	Iter:86 train-loss:0.336545 valid-loss:0.551082  train-accuracy:0.938063 valid-accuracy:0.898257
# 	Iter:96 train-loss:0.320916 valid-loss:0.551974  train-accuracy:0.943603 valid-accuracy:0.899166

# %%
# Model features
model.make_inspector().features()
# Out:
# ["10Percentile" (1; #0),
#  "90Percentile" (1; #1),
#  "Energy" (1; #2),
#  "Entropy" (1; #3),
#  "InterquartileRange" (1; #4),
#  "Kurtosis" (1; #5),
#  "Maximum" (1; #6),
#  "Mean" (1; #7),
#  "MeanAbsoluteDeviation" (1; #8),
#  "Median" (1; #9),
#  "Minimum" (1; #10),
#  "Range" (1; #11),
#  "RobustMeanAbsoluteDeviation" (1; #12),
#  "RootMeanSquared" (1; #13),
#  "Skewness" (1; #14),
#  "TotalEnergy" (1; #15),
#  "Uniformity" (1; #16),
#  "Variance" (1; #17)]

# %%
# Feature importance
model.make_inspector().variable_importances()
# Out:
# {'INV_MEAN_MIN_DEPTH': [("Median" (1; #9), 0.2573868728174499),
#   ("90Percentile" (1; #1), 0.2427280357591792),
#   ("Maximum" (1; #6), 0.23663064356367366),
#   ("Minimum" (1; #10), 0.21110649452194605),
#   ("Skewness" (1; #14), 0.20453071262424358),
#   ("Mean" (1; #7), 0.2002675718842436),
#   ("10Percentile" (1; #0), 0.1995434616271358),
#   ("TotalEnergy" (1; #15), 0.19151246702876484),
#   ("Uniformity" (1; #16), 0.19065309490408155),
#   ("RootMeanSquared" (1; #13), 0.18883549120646584),
#   ("Range" (1; #11), 0.18272339373188293),
#   ("Energy" (1; #2), 0.1822802589183302),
#   ("Entropy" (1; #3), 0.1777224158508327),
#   ("Kurtosis" (1; #5), 0.17726748330181855),
#   ("Variance" (1; #17), 0.17590513049183754),
#   ("RobustMeanAbsoluteDeviation" (1; #12), 0.1751865100330217),
#   ("InterquartileRange" (1; #4), 0.1743682058562825),
#   ("MeanAbsoluteDeviation" (1; #8), 0.17201113103231258)],
#  'NUM_AS_ROOT': [("Median" (1; #9), 14.0),
#   ("90Percentile" (1; #1), 13.0),
#   ("Maximum" (1; #6), 8.0),
#   ("Minimum" (1; #10), 7.0),
#   ("Mean" (1; #7), 5.0),
#   ("RootMeanSquared" (1; #13), 5.0),
#   ("TotalEnergy" (1; #15), 5.0),
#   ("10Percentile" (1; #0), 3.0),
#   ("Energy" (1; #2), 3.0),
#   ("Skewness" (1; #14), 3.0)],
#  'SUM_SCORE': [("90Percentile" (1; #1), 8970.335976292934),
#   ("TotalEnergy" (1; #15), 4652.3130487707695),
#   ("RootMeanSquared" (1; #13), 2358.653251387156),
#   ("Maximum" (1; #6), 2038.7500068174138),
#   ("Uniformity" (1; #16), 1694.9816660287224),
#   ("Mean" (1; #7), 1611.8336973883252),
#   ("10Percentile" (1; #0), 1519.7083169461694),
#   ("Median" (1; #9), 1507.451882702931),
#   ("Skewness" (1; #14), 898.6615057271835),
#   ("Energy" (1; #2), 557.7555440435498),
#   ("Minimum" (1; #10), 529.8403063850932),
#   ("Entropy" (1; #3), 468.1787470819012),
#   ("Range" (1; #11), 438.45679852528957),
#   ("Kurtosis" (1; #5), 274.7802976166928),
#   ("Variance" (1; #17), 215.12910210617514),
#   ("InterquartileRange" (1; #4), 203.1749399884388),
#   ("RobustMeanAbsoluteDeviation" (1; #12), 90.95402369575461),
#   ("MeanAbsoluteDeviation" (1; #8), 66.96120316418035)],
#  'NUM_NODES': [("Maximum" (1; #6), 225.0),
#   ("Median" (1; #9), 217.0),
#   ("Skewness" (1; #14), 180.0),
#   ("90Percentile" (1; #1), 173.0),
#   ("10Percentile" (1; #0), 133.0),
#   ("Range" (1; #11), 109.0),
#   ("Uniformity" (1; #16), 103.0),
#   ("Minimum" (1; #10), 101.0),
#   ("Mean" (1; #7), 98.0),
#   ("Kurtosis" (1; #5), 79.0),
#   ("Entropy" (1; #3), 60.0),
#   ("Variance" (1; #17), 57.0),
#   ("InterquartileRange" (1; #4), 55.0),
#   ("TotalEnergy" (1; #15), 45.0),
#   ("RootMeanSquared" (1; #13), 40.0),
#   ("Energy" (1; #2), 32.0),
#   ("RobustMeanAbsoluteDeviation" (1; #12), 28.0),
#   ("MeanAbsoluteDeviation" (1; #8), 22.0)]}

# %%
# Model self evaluation
model.make_inspector().evaluation()
# Out:
# Evaluation(num_examples=None, accuracy=0.8962569236755371, loss=0.5430983304977417, rmse=None, ndcg=None, aucs=None, auuc=None, qini=None)

# %%
logs = model.make_inspector().training_logs()

plt.figure(figsize=(12, 4))
plt.subplot(1, 2, 1)
plt.plot([log.num_trees for log in logs], [log.evaluation.accuracy for log in logs])
plt.xlabel("Number of trees")
plt.ylabel("Accuracy (out-of-bag)")
plt.subplot(1, 2, 2)
plt.plot([log.num_trees for log in logs], [log.evaluation.loss for log in logs])
plt.xlabel("Number of trees")
plt.ylabel("Logloss (out-of-bag)")
plt.show()

# %% [markdown]
# Calculate the score of our hold-out validation dataset

# %%
predictions = model.predict(val_ds)
y_true      = validation_data["label"]

from sklearn.metrics import roc_auc_score
ROC_AUC = roc_auc_score(y_true, predictions)
print("The ROC AUC score is %.5f" % ROC_AUC )
# Out:
# 1/5 [=====>........................] - ETA: 0s
# 5/5 [==============================] - 0s 4ms/step
# The ROC AUC score is 0.99021

# %%
# Compute binary classification metrics with sklearn
import numpy as np
from sklearn.metrics import (
    accuracy_score,
    precision_score,
    recall_score,
    f1_score,
    roc_auc_score,
    average_precision_score,
    confusion_matrix,
    classification_report,
    matthews_corrcoef,
    log_loss,
    brier_score_loss,
)

# Get predictions (probabilities or class labels)
preds = model.predict(test_ds)
# If model outputs probabilities, convert to labels by threshold 0.5
if preds.ndim == 2:
    # For TFDF classification, preds may be class probabilities with shape (N, 2)
    if preds.shape[1] == 2:
        pos_probs = preds[:, 1]
    else:
        # If single-probability column (positive class)
        pos_probs = preds[:, -1]
    y_pred = (pos_probs >= 0.5).astype(int)
else:
    # Already class labels
    y_pred = preds.astype(int)
    pos_probs = None

# Ground truth labels (must be 0/1 integers)
y_true = test_data["label"].astype(int).to_numpy()

# Core metrics
metrics = {}
metrics["accuracy"] = accuracy_score(y_true, y_pred)
metrics["precision"] = precision_score(y_true, y_pred, zero_division=0)
metrics["recall"] = recall_score(y_true, y_pred, zero_division=0)
metrics["f1"] = f1_score(y_true, y_pred, zero_division=0)
metrics["mcc"] = matthews_corrcoef(y_true, y_pred)

# Probabilistic metrics (only if we have probabilities)
if pos_probs is not None:
    metrics["roc_auc"] = roc_auc_score(y_true, pos_probs)
    metrics["pr_auc"] = average_precision_score(y_true, pos_probs)
    metrics["log_loss"] = log_loss(y_true, pos_probs, labels=[0,1])
    metrics["brier_score"] = brier_score_loss(y_true, pos_probs)

# Confusion matrix and detailed report
cm = confusion_matrix(y_true, y_pred, labels=[0,1])
report = classification_report(y_true, y_pred, digits=4)

print("Sklearn binary metrics:")
for k, v in metrics.items():
    print(f"{k}: {v:.4f}")
print("\nConfusion matrix:\n", cm)
print("\nClassification report:\n", report)
# Out:
# 1/9 [==>...........................] - ETA: 0s
# 9/9 [==============================] - 0s 5ms/step
# Sklearn binary metrics:
# accuracy: 0.9588
# precision: 0.7552
# recall: 0.8664
# f1: 0.8070
# mcc: 0.7864
# roc_auc: 0.9559
# pr_auc: 0.8805
# log_loss: 0.1716
# brier_score: 0.0396
#
# Confusion matrix:
#  [[7763  248]
#  [ 118  765]]
#
# Classification report:
#                precision    recall  f1-score   support
#
#            0     0.9850    0.9690    0.9770      8011
#            1     0.7552    0.8664    0.8070       883
#
#     accuracy                         0.9588      8894
#    macro avg     0.8701    0.9177    0.8920      8894
# weighted avg     0.9622    0.9588    0.9601      8894
