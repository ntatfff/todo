# %%
# Import packages and modules
import numpy  as np
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow_decision_forests as tfdf

from sklearn.model_selection import train_test_split
# Out:
# 2026-09-11 08:12:24.277860: I tensorflow/core/util/port.cc:113] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2026-09-11 08:12:24.323626: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2026-09-11 08:12:29.624738: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
# Check the version of TensorFlow Decision Forests
print("Found TensorFlow Decision Forests v" + tfdf.__version__)
# Out:
# Found TensorFlow Decision Forests v1.9.1

# %%
datasetPath = "dataset/10p/all/kernel3/"

# %%
# Parameters
datasetPath = "dataset/10p/glrlm/kernel4/"

# %%
# train/validation/test = 70/10/20
train_data = pd.read_csv(f"{datasetPath}dataset.train.csv")
validation_data = pd.read_csv(f"{datasetPath}dataset.validation.csv")
test_data = pd.read_csv(f"{datasetPath}dataset.test.csv")

# %%
from sklearn.utils.class_weight import compute_class_weight

# tinh class weight tren tap train
classes = np.array([0, 1])
weights = compute_class_weight(class_weight="balanced", classes=classes, y=train_data["label"])
class_weight = {0: weights[0], 1: weights[1]}

# gan sample_weight cho tung dong
train_data["sample_weight"] = train_data["label"].map(class_weight)
validation_data["sample_weight"] = validation_data["label"].map(class_weight)
test_data["sample_weight"] = test_data["label"].map(class_weight)

# Convert the dataset into a TensorFlow dataset.
train_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    train_data, label="label", weight="sample_weight"
)         
val_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    validation_data, label="label", weight="sample_weight"
)
test_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    test_data, label="label", weight="sample_weight"
)
# Out:
# 2026-09-11 08:12:44.301296: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:984] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2026-09-11 08:12:44.302976: W tensorflow/core/common_runtime/gpu/gpu_device.cc:2251] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...

# %%
import keras

# %%
# %%time

# Train a Gradient Boosted Trees model.
model = tfdf.keras.GradientBoostedTreesModel()

# Add evaluation metrics
model.compile(
    metrics=["accuracy"]
)
model.fit(x=train_ds)

# # Train a Gradient Boosted Trees model.
# model = tfdf.keras.GradientBoostedTreesModel(num_trees=1500)
# model.fit(train_ds)
# Out:
# Use /tmp/tmpfx368n8o as temporary training directory
# Reading training dataset...
# [WARNING 26-09-11 08:12:44.4331 UTC gradient_boosted_trees.cc:1840] "goss_alpha" set but "sampling_method" not equal to "GOSS".
# [WARNING 26-09-11 08:12:44.4331 UTC gradient_boosted_trees.cc:1851] "goss_beta" set but "sampling_method" not equal to "GOSS".
# [WARNING 26-09-11 08:12:44.4331 UTC gradient_boosted_trees.cc:1865] "selective_gradient_boosting_ratio" set but "sampling_method" not equal to "SELGB".
# Training dataset read in 0:00:03.206128. Found 13938 examples.
# Training model...
# Model trained in 0:00:00.954993
# Compiling model...
# [INFO 26-09-11 08:12:48.6203 UTC kernel.cc:1233] Loading model from path /tmp/tmpfx368n8o/model/ with prefix 3298af04926e4434
# [INFO 26-09-11 08:12:48.6225 UTC quick_scorer_extended.cc:911] The binary was compiled without AVX2 support, but your CPU supports it. Enable it for faster model inference.
# [INFO 26-09-11 08:12:48.6227 UTC abstract_model.cc:1362] Engine "GradientBoostedTreesQuickScorerExtended" built
# [INFO 26-09-11 08:12:48.6227 UTC kernel.cc:1061] Use fast generic engine
# Model compiled.
# CPU times: user 11.5 s, sys: 492 ms, total: 12 s
# Wall time: 9.06 s

# %%
# Evaluate the model
evaluate = model.evaluate(val_ds, return_dict=True)
print()

for name, value in evaluate.items():
    print(f"{name}: {value:.4f}")
# Out:
# WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 1/2 [==============>...............] - ETA: 3s - loss: 0.0000e+00 - accuracy: 0.9820
# 2/2 [==============================] - 4s 12ms/step - loss: 0.0000e+00 - accuracy: 0.9754
# loss: 0.0000
# accuracy: 0.9754

# %%
# Model Summary
model.summary()
# Out:
# Model: "gradient_boosted_trees_model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
# =================================================================
# Total params: 1 (1.00 Byte)
# Trainable params: 0 (0.00 Byte)
# Non-trainable params: 1 (1.00 Byte)
# _________________________________________________________________
# Type: "GRADIENT_BOOSTED_TREES"
# Task: CLASSIFICATION
# Label: "__LABEL"
#
# Input Features (16):
# 	GrayLevelNonUniformity
# 	GrayLevelNonUniformityNormalized
# 	GrayLevelVariance
# 	HighGrayLevelRunEmphasis
# 	LongRunEmphasis
# 	LongRunHighGrayLevelEmphasis
# 	LongRunLowGrayLevelEmphasis
# 	LowGrayLevelRunEmphasis
# 	RunEntropy
# 	RunLengthNonUniformity
# 	RunLengthNonUniformityNormalized
# 	RunPercentage
# 	RunVariance
# 	ShortRunEmphasis
# 	ShortRunHighGrayLevelEmphasis
# 	ShortRunLowGrayLevelEmphasis
#
# Trained with weights
#
# Variable Importance: INV_MEAN_MIN_DEPTH:
#     1.     "LongRunHighGrayLevelEmphasis"  0.875169 ################
#     2.                       "RunEntropy"  0.196687
#     3.    "ShortRunHighGrayLevelEmphasis"  0.193372
#     4.          "LowGrayLevelRunEmphasis"  0.187741
#     5. "RunLengthNonUniformityNormalized"  0.187035
#     6.     "ShortRunLowGrayLevelEmphasis"  0.184350
#     7.                      "RunVariance"  0.184015
#     8.         "HighGrayLevelRunEmphasis"  0.183579
#     9.                 "ShortRunEmphasis"  0.183520
#    10.           "GrayLevelNonUniformity"  0.183174
#    11. "GrayLevelNonUniformityNormalized"  0.179789
#    12.      "LongRunLowGrayLevelEmphasis"  0.178108
#    13.                    "RunPercentage"  0.176650
#    14.                  "LongRunEmphasis"  0.176145
#    15.                "GrayLevelVariance"  0.174693
#    16.           "RunLengthNonUniformity"  0.173910
#
# Variable Importance: NUM_AS_ROOT:
#     1.  "LongRunHighGrayLevelEmphasis" 40.000000 ################
#     2. "ShortRunHighGrayLevelEmphasis"  1.000000
#     3.  "ShortRunLowGrayLevelEmphasis"  1.000000
#
# Variable Importance: NUM_NODES:
#     1.     "LongRunHighGrayLevelEmphasis" 246.000000 ################
#     2.                       "RunEntropy" 108.000000 #####
#     3.    "ShortRunHighGrayLevelEmphasis" 96.000000 ####
#     4.                      "RunVariance" 73.000000 ###
#     5.          "LowGrayLevelRunEmphasis" 68.000000 ##
#     6.     "ShortRunLowGrayLevelEmphasis" 68.000000 ##
#     7.      "LongRunLowGrayLevelEmphasis" 67.000000 ##
#     8. "GrayLevelNonUniformityNormalized" 59.000000 ##
#     9. "RunLengthNonUniformityNormalized" 56.000000 #
#    10.           "GrayLevelNonUniformity" 55.000000 #
#    11.         "HighGrayLevelRunEmphasis" 54.000000 #
#    12.                "GrayLevelVariance" 44.000000
#    13.                 "ShortRunEmphasis" 42.000000
#    14.                    "RunPercentage" 40.000000
#    15.                  "LongRunEmphasis" 34.000000
#    16.           "RunLengthNonUniformity" 32.000000
#
# Variable Importance: SUM_SCORE:
#     1.     "LongRunHighGrayLevelEmphasis" 10259.582103 ################
#     2.    "ShortRunHighGrayLevelEmphasis" 827.924950 #
#     3.                       "RunEntropy" 543.995958
#     4.                      "RunVariance" 507.130361
#     5.           "GrayLevelNonUniformity" 304.886772
#     6.     "ShortRunLowGrayLevelEmphasis" 286.967216
#     7. "RunLengthNonUniformityNormalized" 264.789385
#     8.      "LongRunLowGrayLevelEmphasis" 241.067419
#     9.         "HighGrayLevelRunEmphasis" 239.644892
#    10.          "LowGrayLevelRunEmphasis" 217.513297
#    11.                 "ShortRunEmphasis" 191.114396
#    12.                "GrayLevelVariance" 146.880518
#    13. "GrayLevelNonUniformityNormalized" 132.988604
#    14.                  "LongRunEmphasis" 131.955088
#    15.                    "RunPercentage" 77.318205
#    16.           "RunLengthNonUniformity" 75.409720
#
#
#
# Loss: BINOMIAL_LOG_LIKELIHOOD
# Validation loss value: 0.6331
# Number of trees per iteration: 1
# Node format: NOT_SET
# Number of trees: 42
# Total number of nodes: 2326
#
# Number of nodes by tree:
# Count: 42 Average: 55.381 StdDev: 6.09821
# Min: 39 Max: 63 Ignored: 0
# ----------------------------------------------
# [ 39, 40) 1   2.38%   2.38% #
# [ 40, 41) 0   0.00%   2.38%
# [ 41, 42) 0   0.00%   2.38%
# [ 42, 44) 1   2.38%   4.76% #
# [ 44, 45) 0   0.00%   4.76%
# [ 45, 46) 3   7.14%  11.90% ####
# [ 46, 47) 0   0.00%  11.90%
# [ 47, 49) 1   2.38%  14.29% #
# [ 49, 50) 1   2.38%  16.67% #
# [ 50, 51) 0   0.00%  16.67%
# [ 51, 52) 5  11.90%  28.57% ######
# [ 52, 54) 3   7.14%  35.71% ####
# [ 54, 55) 0   0.00%  35.71%
# [ 55, 56) 5  11.90%  47.62% ######
# [ 56, 57) 0   0.00%  47.62%
# [ 57, 59) 3   7.14%  54.76% ####
# [ 59, 60) 8  19.05%  73.81% ##########
# [ 60, 61) 0   0.00%  73.81%
# [ 61, 62) 6  14.29%  88.10% ########
# [ 62, 63] 5  11.90% 100.00% ######
#
# Depth by leafs:
# Count: 1184 Average: 4.89189 StdDev: 0.383532
# Min: 2 Max: 5 Ignored: 0
# ----------------------------------------------
# [ 2, 3)    2   0.17%   0.17%
# [ 3, 4)   24   2.03%   2.20%
# [ 4, 5)   74   6.25%   8.45% #
# [ 5, 5] 1084  91.55% 100.00% ##########
#
# Number of training obs by leaf:
# Count: 1184 Average: 444.867 StdDev: 929.242
# Min: 5 Max: 8012 Ignored: 0
# ----------------------------------------------
# [    5,  405) 923  77.96%  77.96% ##########
# [  405,  805)  89   7.52%  85.47% #
# [  805, 1206)  34   2.87%  88.34%
# [ 1206, 1606)  34   2.87%  91.22%
# [ 1606, 2007)  19   1.60%  92.82%
# [ 2007, 2407)  18   1.52%  94.34%
# [ 2407, 2807)  18   1.52%  95.86%
# [ 2807, 3208)   9   0.76%  96.62%
# [ 3208, 3608)   6   0.51%  97.13%
# [ 3608, 4009)  14   1.18%  98.31%
# [ 4009, 4409)   8   0.68%  98.99%
# [ 4409, 4809)   4   0.34%  99.32%
# [ 4809, 5210)   3   0.25%  99.58%
# [ 5210, 5610)   1   0.08%  99.66%
# [ 5610, 6011)   2   0.17%  99.83%
# [ 6011, 6411)   1   0.08%  99.92%
# [ 6411, 6811)   0   0.00%  99.92%
# [ 6811, 7212)   0   0.00%  99.92%
# [ 7212, 7612)   0   0.00%  99.92%
# [ 7612, 8012]   1   0.08% 100.00%
#
# Attribute in nodes:
# 	246 : LongRunHighGrayLevelEmphasis [NUMERICAL]
# 	108 : RunEntropy [NUMERICAL]
# 	96 : ShortRunHighGrayLevelEmphasis [NUMERICAL]
# 	73 : RunVariance [NUMERICAL]
# 	68 : ShortRunLowGrayLevelEmphasis [NUMERICAL]
# 	68 : LowGrayLevelRunEmphasis [NUMERICAL]
# 	67 : LongRunLowGrayLevelEmphasis [NUMERICAL]
# 	59 : GrayLevelNonUniformityNormalized [NUMERICAL]
# 	56 : RunLengthNonUniformityNormalized [NUMERICAL]
# 	55 : GrayLevelNonUniformity [NUMERICAL]
# 	54 : HighGrayLevelRunEmphasis [NUMERICAL]
# 	44 : GrayLevelVariance [NUMERICAL]
# 	42 : ShortRunEmphasis [NUMERICAL]
# 	40 : RunPercentage [NUMERICAL]
# 	34 : LongRunEmphasis [NUMERICAL]
# 	32 : RunLengthNonUniformity [NUMERICAL]
#
# Attribute in nodes with depth <= 0:
# 	40 : LongRunHighGrayLevelEmphasis [NUMERICAL]
# 	1 : ShortRunLowGrayLevelEmphasis [NUMERICAL]
# 	1 : ShortRunHighGrayLevelEmphasis [NUMERICAL]
#
# Attribute in nodes with depth <= 1:
# 	91 : LongRunHighGrayLevelEmphasis [NUMERICAL]
# 	6 : ShortRunHighGrayLevelEmphasis [NUMERICAL]
# 	5 : LowGrayLevelRunEmphasis [NUMERICAL]
# 	4 : ShortRunEmphasis [NUMERICAL]
# 	4 : GrayLevelNonUniformity [NUMERICAL]
# 	3 : RunVariance [NUMERICAL]
# 	3 : RunLengthNonUniformityNormalized [NUMERICAL]
# 	3 : RunEntropy [NUMERICAL]
# 	3 : HighGrayLevelRunEmphasis [NUMERICAL]
# 	2 : ShortRunLowGrayLevelEmphasis [NUMERICAL]
# 	1 : LongRunEmphasis [NUMERICAL]
# 	1 : GrayLevelNonUniformityNormalized [NUMERICAL]
#
# Attribute in nodes with depth <= 2:
# 	119 : LongRunHighGrayLevelEmphasis [NUMERICAL]
# 	24 : RunEntropy [NUMERICAL]
# 	23 : ShortRunHighGrayLevelEmphasis [NUMERICAL]
# 	20 : LowGrayLevelRunEmphasis [NUMERICAL]
# 	18 : RunLengthNonUniformityNormalized [NUMERICAL]
# 	14 : HighGrayLevelRunEmphasis [NUMERICAL]
# 	13 : ShortRunEmphasis [NUMERICAL]
# 	10 : RunPercentage [NUMERICAL]
# 	10 : GrayLevelNonUniformity [NUMERICAL]
# 	9 : ShortRunLowGrayLevelEmphasis [NUMERICAL]
# 	9 : GrayLevelNonUniformityNormalized [NUMERICAL]
# 	7 : RunVariance [NUMERICAL]
# 	6 : LongRunLowGrayLevelEmphasis [NUMERICAL]
# 	5 : LongRunEmphasis [NUMERICAL]
# 	3 : GrayLevelVariance [NUMERICAL]
# 	2 : RunLengthNonUniformity [NUMERICAL]
#
# Attribute in nodes with depth <= 3:
# 	162 : LongRunHighGrayLevelEmphasis [NUMERICAL]
# 	58 : RunEntropy [NUMERICAL]
# 	51 : ShortRunHighGrayLevelEmphasis [NUMERICAL]
# 	38 : RunVariance [NUMERICAL]
# 	36 : RunLengthNonUniformityNormalized [NUMERICAL]
# 	33 : LowGrayLevelRunEmphasis [NUMERICAL]
# 	29 : GrayLevelNonUniformity [NUMERICAL]
# 	28 : ShortRunLowGrayLevelEmphasis [NUMERICAL]
# 	27 : LongRunLowGrayLevelEmphasis [NUMERICAL]
# 	27 : GrayLevelNonUniformityNormalized [NUMERICAL]
# 	25 : HighGrayLevelRunEmphasis [NUMERICAL]
# 	23 : RunPercentage [NUMERICAL]
# 	21 : ShortRunEmphasis [NUMERICAL]
# 	16 : GrayLevelVariance [NUMERICAL]
# 	14 : LongRunEmphasis [NUMERICAL]
# 	12 : RunLengthNonUniformity [NUMERICAL]
#
# Attribute in nodes with depth <= 5:
# 	246 : LongRunHighGrayLevelEmphasis [NUMERICAL]
# 	108 : RunEntropy [NUMERICAL]
# 	96 : ShortRunHighGrayLevelEmphasis [NUMERICAL]
# 	73 : RunVariance [NUMERICAL]
# 	68 : ShortRunLowGrayLevelEmphasis [NUMERICAL]
# 	68 : LowGrayLevelRunEmphasis [NUMERICAL]
# 	67 : LongRunLowGrayLevelEmphasis [NUMERICAL]
# 	59 : GrayLevelNonUniformityNormalized [NUMERICAL]
# 	56 : RunLengthNonUniformityNormalized [NUMERICAL]
# 	55 : GrayLevelNonUniformity [NUMERICAL]
# 	54 : HighGrayLevelRunEmphasis [NUMERICAL]
# 	44 : GrayLevelVariance [NUMERICAL]
# 	42 : ShortRunEmphasis [NUMERICAL]
# 	40 : RunPercentage [NUMERICAL]
# 	34 : LongRunEmphasis [NUMERICAL]
# 	32 : RunLengthNonUniformity [NUMERICAL]
#
# Condition type in nodes:
# 	1142 : HigherCondition
# Condition type in nodes with depth <= 0:
# 	42 : HigherCondition
# Condition type in nodes with depth <= 1:
# 	126 : HigherCondition
# Condition type in nodes with depth <= 2:
# 	292 : HigherCondition
# Condition type in nodes with depth <= 3:
# 	600 : HigherCondition
# Condition type in nodes with depth <= 5:
# 	1142 : HigherCondition
#
# Training logs:
# Number of iteration to final model: 42
# 	Iter:1 train-loss:1.251022 valid-loss:1.271649  train-accuracy:0.898341 valid-accuracy:0.849781
# 	Iter:2 train-loss:1.138482 valid-loss:1.173065  train-accuracy:0.909074 valid-accuracy:0.865519
# 	Iter:3 train-loss:1.043873 valid-loss:1.094248  train-accuracy:0.913395 valid-accuracy:0.848979
# 	Iter:4 train-loss:0.963356 valid-loss:1.027053  train-accuracy:0.913816 valid-accuracy:0.854287
# 	Iter:5 train-loss:0.897020 valid-loss:0.977209  train-accuracy:0.916266 valid-accuracy:0.847807
# 	Iter:6 train-loss:0.834592 valid-loss:0.928303  train-accuracy:0.915994 valid-accuracy:0.852682
# 	Iter:16 train-loss:0.492463 valid-loss:0.688281  train-accuracy:0.933948 valid-accuracy:0.856817
# 	Iter:26 train-loss:0.364618 valid-loss:0.644686  train-accuracy:0.950074 valid-accuracy:0.853484
# 	Iter:36 train-loss:0.304209 valid-loss:0.637555  train-accuracy:0.956551 valid-accuracy:0.860952
# 	Iter:46 train-loss:0.263910 valid-loss:0.641831  train-accuracy:0.964171 valid-accuracy:0.860952
# 	Iter:56 train-loss:0.234769 valid-loss:0.649019  train-accuracy:0.969091 valid-accuracy:0.866198
# 	Iter:66 train-loss:0.217207 valid-loss:0.668017  train-accuracy:0.972969 valid-accuracy:0.862433

# %%
# Model features
model.make_inspector().features()
# Out:
# ["GrayLevelNonUniformity" (1; #0),
#  "GrayLevelNonUniformityNormalized" (1; #1),
#  "GrayLevelVariance" (1; #2),
#  "HighGrayLevelRunEmphasis" (1; #3),
#  "LongRunEmphasis" (1; #4),
#  "LongRunHighGrayLevelEmphasis" (1; #5),
#  "LongRunLowGrayLevelEmphasis" (1; #6),
#  "LowGrayLevelRunEmphasis" (1; #7),
#  "RunEntropy" (1; #8),
#  "RunLengthNonUniformity" (1; #9),
#  "RunLengthNonUniformityNormalized" (1; #10),
#  "RunPercentage" (1; #11),
#  "RunVariance" (1; #12),
#  "ShortRunEmphasis" (1; #13),
#  "ShortRunHighGrayLevelEmphasis" (1; #14),
#  "ShortRunLowGrayLevelEmphasis" (1; #15)]

# %%
# Feature importance
model.make_inspector().variable_importances()
# Out:
# {'INV_MEAN_MIN_DEPTH': [("LongRunHighGrayLevelEmphasis" (1; #5),
#    0.8751688211460545),
#   ("RunEntropy" (1; #8), 0.1966867838850875),
#   ("ShortRunHighGrayLevelEmphasis" (1; #14), 0.19337167299321018),
#   ("LowGrayLevelRunEmphasis" (1; #7), 0.1877405285646595),
#   ("RunLengthNonUniformityNormalized" (1; #10), 0.18703544577756753),
#   ("ShortRunLowGrayLevelEmphasis" (1; #15), 0.18435041183252202),
#   ("RunVariance" (1; #12), 0.18401494658396308),
#   ("HighGrayLevelRunEmphasis" (1; #3), 0.18357876364467943),
#   ("ShortRunEmphasis" (1; #13), 0.18352028272983054),
#   ("GrayLevelNonUniformity" (1; #0), 0.18317438031247096),
#   ("GrayLevelNonUniformityNormalized" (1; #1), 0.17978925477358065),
#   ("LongRunLowGrayLevelEmphasis" (1; #6), 0.1781084706194395),
#   ("RunPercentage" (1; #11), 0.17665027832532085),
#   ("LongRunEmphasis" (1; #4), 0.1761450588193358),
#   ("GrayLevelVariance" (1; #2), 0.17469326862174817),
#   ("RunLengthNonUniformity" (1; #9), 0.1739096426724212)],
#  'SUM_SCORE': [("LongRunHighGrayLevelEmphasis" (1; #5), 10259.582102616196),
#   ("ShortRunHighGrayLevelEmphasis" (1; #14), 827.9249501248875),
#   ("RunEntropy" (1; #8), 543.9959575762872),
#   ("RunVariance" (1; #12), 507.130360653527),
#   ("GrayLevelNonUniformity" (1; #0), 304.88677161475755),
#   ("ShortRunLowGrayLevelEmphasis" (1; #15), 286.96721577884415),
#   ("RunLengthNonUniformityNormalized" (1; #10), 264.789384813734),
#   ("LongRunLowGrayLevelEmphasis" (1; #6), 241.06741862699243),
#   ("HighGrayLevelRunEmphasis" (1; #3), 239.64489156767326),
#   ("LowGrayLevelRunEmphasis" (1; #7), 217.51329700575258),
#   ("ShortRunEmphasis" (1; #13), 191.1143963750421),
#   ("GrayLevelVariance" (1; #2), 146.88051768368365),
#   ("GrayLevelNonUniformityNormalized" (1; #1), 132.98860350969863),
#   ("LongRunEmphasis" (1; #4), 131.95508834089082),
#   ("RunPercentage" (1; #11), 77.31820539528145),
#   ("RunLengthNonUniformity" (1; #9), 75.40972005359629)],
#  'NUM_AS_ROOT': [("LongRunHighGrayLevelEmphasis" (1; #5), 40.0),
#   ("ShortRunHighGrayLevelEmphasis" (1; #14), 1.0),
#   ("ShortRunLowGrayLevelEmphasis" (1; #15), 1.0)],
#  'NUM_NODES': [("LongRunHighGrayLevelEmphasis" (1; #5), 246.0),
#   ("RunEntropy" (1; #8), 108.0),
#   ("ShortRunHighGrayLevelEmphasis" (1; #14), 96.0),
#   ("RunVariance" (1; #12), 73.0),
#   ("LowGrayLevelRunEmphasis" (1; #7), 68.0),
#   ("ShortRunLowGrayLevelEmphasis" (1; #15), 68.0),
#   ("LongRunLowGrayLevelEmphasis" (1; #6), 67.0),
#   ("GrayLevelNonUniformityNormalized" (1; #1), 59.0),
#   ("RunLengthNonUniformityNormalized" (1; #10), 56.0),
#   ("GrayLevelNonUniformity" (1; #0), 55.0),
#   ("HighGrayLevelRunEmphasis" (1; #3), 54.0),
#   ("GrayLevelVariance" (1; #2), 44.0),
#   ("ShortRunEmphasis" (1; #13), 42.0),
#   ("RunPercentage" (1; #11), 40.0),
#   ("LongRunEmphasis" (1; #4), 34.0),
#   ("RunLengthNonUniformity" (1; #9), 32.0)]}

# %%
# Model self evaluation
model.make_inspector().evaluation()
# Out:
# Evaluation(num_examples=None, accuracy=0.8557062745094299, loss=0.6331003308296204, rmse=None, ndcg=None, aucs=None, auuc=None, qini=None)

# %%
logs = model.make_inspector().training_logs()

plt.figure(figsize=(12, 4))
plt.subplot(1, 2, 1)
plt.plot([log.num_trees for log in logs], [log.evaluation.accuracy for log in logs])
plt.xlabel("Number of trees")
plt.ylabel("Accuracy (out-of-bag)")
plt.subplot(1, 2, 2)
plt.plot([log.num_trees for log in logs], [log.evaluation.loss for log in logs])
plt.xlabel("Number of trees")
plt.ylabel("Logloss (out-of-bag)")
plt.show()

# %% [markdown]
# Calculate the score of our hold-out validation dataset

# %%
predictions = model.predict(val_ds)
y_true      = validation_data["label"]

from sklearn.metrics import roc_auc_score
ROC_AUC = roc_auc_score(y_true, predictions)
print("The ROC AUC score is %.5f" % ROC_AUC )
# Out:
# 1/2 [==============>...............] - ETA: 0s
# 2/2 [==============================] - 0s 5ms/step
# The ROC AUC score is 0.99817

# %%
# Compute binary classification metrics with sklearn
import numpy as np
from sklearn.metrics import (
    accuracy_score,
    precision_score,
    recall_score,
    f1_score,
    roc_auc_score,
    average_precision_score,
    confusion_matrix,
    classification_report,
    matthews_corrcoef,
    log_loss,
    brier_score_loss,
)

# Get predictions (probabilities or class labels)
preds = model.predict(test_ds)
# If model outputs probabilities, convert to labels by threshold 0.5
if preds.ndim == 2:
    # For TFDF classification, preds may be class probabilities with shape (N, 2)
    if preds.shape[1] == 2:
        pos_probs = preds[:, 1]
    else:
        # If single-probability column (positive class)
        pos_probs = preds[:, -1]
    y_pred = (pos_probs >= 0.5).astype(int)
else:
    # Already class labels
    y_pred = preds.astype(int)
    pos_probs = None

# Ground truth labels (must be 0/1 integers)
y_true = test_data["label"].astype(int).to_numpy()

# Core metrics
metrics = {}
metrics["accuracy"] = accuracy_score(y_true, y_pred)
metrics["precision"] = precision_score(y_true, y_pred, zero_division=0)
metrics["recall"] = recall_score(y_true, y_pred, zero_division=0)
metrics["f1"] = f1_score(y_true, y_pred, zero_division=0)
metrics["mcc"] = matthews_corrcoef(y_true, y_pred)

# Probabilistic metrics (only if we have probabilities)
if pos_probs is not None:
    metrics["roc_auc"] = roc_auc_score(y_true, pos_probs)
    metrics["pr_auc"] = average_precision_score(y_true, pos_probs)
    metrics["log_loss"] = log_loss(y_true, pos_probs, labels=[0,1])
    metrics["brier_score"] = brier_score_loss(y_true, pos_probs)

# Confusion matrix and detailed report
cm = confusion_matrix(y_true, y_pred, labels=[0,1])
report = classification_report(y_true, y_pred, digits=4)

print("Sklearn binary metrics:")
for k, v in metrics.items():
    print(f"{k}: {v:.4f}")
print("\nConfusion matrix:\n", cm)
print("\nClassification report:\n", report)
# Out:
# 1/5 [=====>........................] - ETA: 0s
# 5/5 [==============================] - 0s 5ms/step
# Sklearn binary metrics:
# accuracy: 0.9620
# precision: 0.7833
# recall: 0.8463
# f1: 0.8136
# mcc: 0.7932
# roc_auc: 0.9652
# pr_auc: 0.8630
# log_loss: 0.1372
# brier_score: 0.0334
#
# Confusion matrix:
#  [[3673   96]
#  [  63  347]]
#
# Classification report:
#                precision    recall  f1-score   support
#
#            0     0.9831    0.9745    0.9788      3769
#            1     0.7833    0.8463    0.8136       410
#
#     accuracy                         0.9620      4179
#    macro avg     0.8832    0.9104    0.8962      4179
# weighted avg     0.9635    0.9620    0.9626      4179
