# %%
# Import packages and modules
import numpy  as np
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow_decision_forests as tfdf

from sklearn.model_selection import train_test_split
# Out:
# 2026-09-11 08:18:38.501448: I tensorflow/core/util/port.cc:113] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2026-09-11 08:18:38.542321: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2026-09-11 08:18:42.854190: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
# Check the version of TensorFlow Decision Forests
print("Found TensorFlow Decision Forests v" + tfdf.__version__)
# Out:
# Found TensorFlow Decision Forests v1.9.1

# %%
datasetPath = "dataset/10p/all/kernel3/"

# %%
# Parameters
datasetPath = "dataset/10p/all/kernel4/"

# %%
# train/validation/test = 70/10/20
train_data = pd.read_csv(f"{datasetPath}dataset.train.csv")
validation_data = pd.read_csv(f"{datasetPath}dataset.validation.csv")
test_data = pd.read_csv(f"{datasetPath}dataset.test.csv")

# %%
from sklearn.utils.class_weight import compute_class_weight

# tinh class weight tren tap train
classes = np.array([0, 1])
weights = compute_class_weight(class_weight="balanced", classes=classes, y=train_data["label"])
class_weight = {0: weights[0], 1: weights[1]}

# gan sample_weight cho tung dong
train_data["sample_weight"] = train_data["label"].map(class_weight)
validation_data["sample_weight"] = validation_data["label"].map(class_weight)
test_data["sample_weight"] = test_data["label"].map(class_weight)

# Convert the dataset into a TensorFlow dataset.
train_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    train_data, label="label", weight="sample_weight"
)         
val_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    validation_data, label="label", weight="sample_weight"
)
test_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    test_data, label="label", weight="sample_weight"
)
# Out:
# 2026-09-11 08:18:54.878486: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:984] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2026-09-11 08:18:54.879626: W tensorflow/core/common_runtime/gpu/gpu_device.cc:2251] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...

# %%
import keras

# %%
# %%time

# Train a Random Forest model.
model = tfdf.keras.RandomForestModel()

# Add evaluation metrics
model.compile(
    metrics=["accuracy"]
)
model.fit(x=train_ds)

# # Train a Gradient Boosted Trees model.
# model = tfdf.keras.GradientBoostedTreesModel(num_trees=1500)
# model.fit(train_ds)
# Out:
# Use /tmp/tmpb8ss95a4 as temporary training directory
# Reading training dataset...
# Training dataset read in 0:00:03.345183. Found 13938 examples.
# Training model...
# Model trained in 0:00:01.440282
# Compiling model...
# [INFO 26-09-11 08:18:59.8217 UTC kernel.cc:1233] Loading model from path /tmp/tmpb8ss95a4/model/ with prefix 93f962256488443a
# [INFO 26-09-11 08:18:59.9320 UTC decision_forest.cc:734] Model loaded with 300 root(s), 96304 node(s), and 93 input feature(s).
# [INFO 26-09-11 08:18:59.9320 UTC abstract_model.cc:1362] Engine "RandomForestOptPred" built
# [INFO 26-09-11 08:18:59.9321 UTC kernel.cc:1061] Use fast generic engine
# Model compiled.
# CPU times: user 21 s, sys: 249 ms, total: 21.2 s
# Wall time: 8.36 s

# %%
# Evaluate the model
evaluate = model.evaluate(val_ds, return_dict=True)
print()

for name, value in evaluate.items():
    print(f"{name}: {value:.4f}")
# Out:
# WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 1/2 [==============>...............] - ETA: 4s - loss: 0.0000e+00 - accuracy: 0.9920
# 2/2 [==============================] - 4s 26ms/step - loss: 0.0000e+00 - accuracy: 0.9928
# loss: 0.0000
# accuracy: 0.9928

# %%
# Model Summary
model.summary()
# Out:
# Model: "random_forest_model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
# =================================================================
# Total params: 1 (1.00 Byte)
# Trainable params: 0 (0.00 Byte)
# Non-trainable params: 1 (1.00 Byte)
# _________________________________________________________________
# Type: "RANDOM_FOREST"
# Task: CLASSIFICATION
# Label: "__LABEL"
#
# Input Features (93):
# 	10Percentile
# 	90Percentile
# 	Autocorrelation
# 	Busyness
# 	ClusterProminence
# 	ClusterShade
# 	ClusterTendency
# 	Coarseness
# 	Complexity
# 	Contrast
# 	Contrast.1
# 	Correlation
# 	DependenceEntropy
# 	DependenceNonUniformity
# 	DependenceNonUniformityNormalized
# 	DependenceVariance
# 	DifferenceAverage
# 	DifferenceEntropy
# 	DifferenceVariance
# 	Energy
# 	Entropy
# 	GrayLevelNonUniformity
# 	GrayLevelNonUniformity.1
# 	GrayLevelNonUniformity.2
# 	GrayLevelNonUniformityNormalized
# 	GrayLevelNonUniformityNormalized.1
# 	GrayLevelVariance
# 	GrayLevelVariance.1
# 	GrayLevelVariance.2
# 	HighGrayLevelEmphasis
# 	HighGrayLevelRunEmphasis
# 	HighGrayLevelZoneEmphasis
# 	Id
# 	Idm
# 	Idmn
# 	Idn
# 	Imc1
# 	Imc2
# 	InterquartileRange
# 	InverseVariance
# 	JointAverage
# 	JointEnergy
# 	JointEntropy
# 	Kurtosis
# 	LargeAreaEmphasis
# 	LargeAreaHighGrayLevelEmphasis
# 	LargeAreaLowGrayLevelEmphasis
# 	LargeDependenceEmphasis
# 	LargeDependenceHighGrayLevelEmphasis
# 	LargeDependenceLowGrayLevelEmphasis
# 	LongRunEmphasis
# 	LongRunHighGrayLevelEmphasis
# 	LongRunLowGrayLevelEmphasis
# 	LowGrayLevelEmphasis
# 	LowGrayLevelRunEmphasis
# 	LowGrayLevelZoneEmphasis
# 	MCC
# 	Maximum
# 	MaximumProbability
# 	Mean
# 	MeanAbsoluteDeviation
# 	Median
# 	Minimum
# 	Range
# 	RobustMeanAbsoluteDeviation
# 	RootMeanSquared
# 	RunEntropy
# 	RunLengthNonUniformity
# 	RunLengthNonUniformityNormalized
# 	RunPercentage
# 	RunVariance
# 	ShortRunEmphasis
# 	ShortRunHighGrayLevelEmphasis
# 	ShortRunLowGrayLevelEmphasis
# 	SizeZoneNonUniformity
# 	SizeZoneNonUniformityNormalized
# 	Skewness
# 	SmallAreaEmphasis
# 	SmallAreaHighGrayLevelEmphasis
# 	SmallAreaLowGrayLevelEmphasis
# 	SmallDependenceEmphasis
# 	SmallDependenceHighGrayLevelEmphasis
# 	SmallDependenceLowGrayLevelEmphasis
# 	Strength
# 	SumAverage
# 	SumEntropy
# 	SumSquares
# 	TotalEnergy
# 	Uniformity
# 	Variance
# 	ZoneEntropy
# 	ZonePercentage
# 	ZoneVariance
#
# Trained with weights
#
# Variable Importance: INV_MEAN_MIN_DEPTH:
#     1.         "LongRunHighGrayLevelEmphasis"  0.124901 ################
#     2. "LargeDependenceHighGrayLevelEmphasis"  0.117468 ###########
#     3.             "GrayLevelNonUniformity.2"  0.116064 ##########
#     4.                         "90Percentile"  0.115780 ##########
#     5.                "HighGrayLevelEmphasis"  0.113038 #########
#     6.                      "Autocorrelation"  0.112737 ########
#     7.                             "Busyness"  0.111895 ########
#     8.            "HighGrayLevelZoneEmphasis"  0.110984 #######
#     9.                           "Coarseness"  0.110920 #######
#    10.                               "Energy"  0.110337 #######
#    11.                      "RootMeanSquared"  0.109508 ######
#    12.                               "Median"  0.109388 ######
#    13.                          "TotalEnergy"  0.108450 ######
#    14.                              "Maximum"  0.108099 ######
#    15.             "HighGrayLevelRunEmphasis"  0.108040 ######
#    16.                           "SumAverage"  0.107773 #####
#    17.                                  "Idn"  0.107550 #####
#    18.                                 "Idmn"  0.106679 #####
#    19.       "LargeAreaHighGrayLevelEmphasis"  0.106193 #####
#    20.                                 "Mean"  0.106183 #####
#    21.                         "JointAverage"  0.104761 ####
#    22.                             "Skewness"  0.104656 ####
#    23.  "SmallDependenceLowGrayLevelEmphasis"  0.103849 ###
#    24.       "SmallAreaHighGrayLevelEmphasis"  0.103212 ###
#    25.        "ShortRunHighGrayLevelEmphasis"  0.102914 ###
#    26.              "DependenceNonUniformity"  0.102846 ###
#    27.                    "DependenceEntropy"  0.102468 ##
#    28.                                 "Imc1"  0.102396 ##
#    29.                      "InverseVariance"  0.102191 ##
#    30.                          "Correlation"  0.102185 ##
#    31.              "LowGrayLevelRunEmphasis"  0.102175 ##
#    32.                         "ClusterShade"  0.102137 ##
#    33.                 "LowGrayLevelEmphasis"  0.102038 ##
#    34.         "ShortRunLowGrayLevelEmphasis"  0.101951 ##
#    35.             "LowGrayLevelZoneEmphasis"  0.101765 ##
#    36. "SmallDependenceHighGrayLevelEmphasis"  0.101416 ##
#    37.              "LargeDependenceEmphasis"  0.101373 ##
#    38.    "DependenceNonUniformityNormalized"  0.101230 ##
#    39.                       "ZonePercentage"  0.101225 ##
#    40.                             "Strength"  0.101095 ##
#    41.                   "DependenceVariance"  0.100968 #
#    42.          "LongRunLowGrayLevelEmphasis"  0.100822 #
#    43.              "SmallDependenceEmphasis"  0.100804 #
#    44.                          "RunVariance"  0.100463 #
#    45.        "LargeAreaLowGrayLevelEmphasis"  0.100441 #
#    46.  "LargeDependenceLowGrayLevelEmphasis"  0.100412 #
#    47.                                  "MCC"  0.100298 #
#    48.                                 "Imc2"  0.100224 #
#    49.                         "10Percentile"  0.100157 #
#    50.                        "RunPercentage"  0.100130 #
#    51.                           "Contrast.1"  0.100011 #
#    52.                      "LongRunEmphasis"  0.099762 #
#    53.                   "MaximumProbability"  0.099758 #
#    54.                              "Minimum"  0.099624 #
#    55.                             "Kurtosis"  0.099551 #
#    56.                                  "Idm"  0.099419 #
#    57.                                "Range"  0.099179
#    58.             "GrayLevelNonUniformity.1"  0.099128
#    59.               "GrayLevelNonUniformity"  0.099120
#    60.                             "Contrast"  0.099095
#    61.                   "DifferenceVariance"  0.099051
#    62.                    "DifferenceEntropy"  0.099016
#    63.        "SmallAreaLowGrayLevelEmphasis"  0.099003
#    64.                           "Uniformity"  0.098975
#    65.                                   "Id"  0.098966
#    66.                           "SumEntropy"  0.098960
#    67.                "SizeZoneNonUniformity"  0.098946
#    68.                    "DifferenceAverage"  0.098914
#    69.               "RunLengthNonUniformity"  0.098830
#    70.                              "Entropy"  0.098781
#    71.                           "RunEntropy"  0.098676
#    72.   "GrayLevelNonUniformityNormalized.1"  0.098663
#    73.                     "ShortRunEmphasis"  0.098657
#    74.                           "Complexity"  0.098639
#    75.                          "ZoneEntropy"  0.098608
#    76.                  "GrayLevelVariance.2"  0.098489
#    77.      "SizeZoneNonUniformityNormalized"  0.098485
#    78.                          "JointEnergy"  0.098464
#    79.                    "ClusterProminence"  0.098411
#    80.     "GrayLevelNonUniformityNormalized"  0.098366
#    81.     "RunLengthNonUniformityNormalized"  0.098361
#    82.                    "SmallAreaEmphasis"  0.098244
#    83.                   "InterquartileRange"  0.098235
#    84.                    "GrayLevelVariance"  0.098022
#    85.          "RobustMeanAbsoluteDeviation"  0.097964
#    86.                    "LargeAreaEmphasis"  0.097958
#    87.                           "SumSquares"  0.097936
#    88.                         "ZoneVariance"  0.097920
#    89.                         "JointEntropy"  0.097904
#    90.                "MeanAbsoluteDeviation"  0.097851
#    91.                  "GrayLevelVariance.1"  0.097724
#    92.                      "ClusterTendency"  0.097594
#    93.                             "Variance"  0.097571
#
# Variable Importance: NUM_AS_ROOT:
#     1.                         "90Percentile" 31.000000 ################
#     2.            "HighGrayLevelZoneEmphasis" 29.000000 ##############
#     3.         "LongRunHighGrayLevelEmphasis" 29.000000 ##############
#     4.                "HighGrayLevelEmphasis" 27.000000 #############
#     5.                               "Energy" 22.000000 ###########
#     6.                      "Autocorrelation" 19.000000 #########
#     7.                      "RootMeanSquared" 19.000000 #########
#     8.             "HighGrayLevelRunEmphasis" 18.000000 #########
#     9.                          "TotalEnergy" 18.000000 #########
#    10.                           "SumAverage" 15.000000 #######
#    11.                                 "Mean" 10.000000 ####
#    12.                              "Maximum"  7.000000 ###
#    13.        "ShortRunHighGrayLevelEmphasis"  7.000000 ###
#    14.                         "JointAverage"  6.000000 ##
#    15.         "ShortRunLowGrayLevelEmphasis"  6.000000 ##
#    16.       "SmallAreaHighGrayLevelEmphasis"  5.000000 ##
#    17.                             "Busyness"  4.000000 #
#    18.                               "Median"  4.000000 #
#    19. "LargeDependenceHighGrayLevelEmphasis"  3.000000 #
#    20.              "LowGrayLevelRunEmphasis"  3.000000 #
#    21.             "LowGrayLevelZoneEmphasis"  3.000000 #
#    22.                 "LowGrayLevelEmphasis"  2.000000
#    23. "SmallDependenceHighGrayLevelEmphasis"  2.000000
#    24.  "SmallDependenceLowGrayLevelEmphasis"  2.000000
#    25.                         "10Percentile"  1.000000
#    26.                    "DependenceEntropy"  1.000000
#    27.               "GrayLevelNonUniformity"  1.000000
#    28.                         "JointEntropy"  1.000000
#    29.        "LargeAreaLowGrayLevelEmphasis"  1.000000
#    30.          "LongRunLowGrayLevelEmphasis"  1.000000
#    31.                                  "MCC"  1.000000
#    32.                              "Minimum"  1.000000
#    33.                           "SumEntropy"  1.000000
#
# Variable Importance: NUM_NODES:
#     1.                                  "Idn" 1877.000000 ################
#     2.                                 "Idmn" 1626.000000 #############
#     3.                             "Skewness" 1045.000000 #######
#     4.             "GrayLevelNonUniformity.2" 1011.000000 #######
#     5.                              "Maximum" 994.000000 #######
#     6.                             "Busyness" 913.000000 ######
#     7.                         "ClusterShade" 906.000000 ######
#     8. "LargeDependenceHighGrayLevelEmphasis" 901.000000 ######
#     9.                           "Coarseness" 894.000000 ######
#    10.                               "Median" 821.000000 #####
#    11.         "LongRunHighGrayLevelEmphasis" 805.000000 #####
#    12.                         "90Percentile" 696.000000 ####
#    13.       "SmallAreaHighGrayLevelEmphasis" 692.000000 ####
#    14.                          "Correlation" 678.000000 ####
#    15.                    "DependenceEntropy" 650.000000 ###
#    16.                                 "Imc1" 643.000000 ###
#    17.                           "Contrast.1" 632.000000 ###
#    18.                             "Kurtosis" 618.000000 ###
#    19.                             "Strength" 607.000000 ###
#    20.                      "Autocorrelation" 593.000000 ###
#    21.            "HighGrayLevelZoneEmphasis" 589.000000 ###
#    22.                                "Range" 587.000000 ###
#    23.       "LargeAreaHighGrayLevelEmphasis" 566.000000 ###
#    24.                                  "MCC" 536.000000 ##
#    25.                                 "Imc2" 533.000000 ##
#    26.                             "Contrast" 520.000000 ##
#    27.                         "JointAverage" 518.000000 ##
#    28. "SmallDependenceHighGrayLevelEmphasis" 518.000000 ##
#    29.                   "DifferenceVariance" 513.000000 ##
#    30.                      "RootMeanSquared" 504.000000 ##
#    31.  "SmallDependenceLowGrayLevelEmphasis" 501.000000 ##
#    32.                               "Energy" 495.000000 ##
#    33.                          "TotalEnergy" 494.000000 ##
#    34.                "HighGrayLevelEmphasis" 485.000000 ##
#    35.                   "DependenceVariance" 481.000000 ##
#    36.                           "SumAverage" 475.000000 ##
#    37.                          "RunVariance" 467.000000 ##
#    38.             "LowGrayLevelZoneEmphasis" 466.000000 ##
#    39.  "LargeDependenceLowGrayLevelEmphasis" 461.000000 #
#    40.                    "DifferenceAverage" 460.000000 #
#    41.                         "10Percentile" 458.000000 #
#    42.             "HighGrayLevelRunEmphasis" 449.000000 #
#    43.                    "DifferenceEntropy" 447.000000 #
#    44.                 "LowGrayLevelEmphasis" 442.000000 #
#    45.                                 "Mean" 442.000000 #
#    46.                   "InterquartileRange" 441.000000 #
#    47.              "LowGrayLevelRunEmphasis" 438.000000 #
#    48.                              "Minimum" 436.000000 #
#    49.        "LargeAreaLowGrayLevelEmphasis" 435.000000 #
#    50.                          "ZoneEntropy" 435.000000 #
#    51.         "ShortRunLowGrayLevelEmphasis" 432.000000 #
#    52.          "LongRunLowGrayLevelEmphasis" 431.000000 #
#    53.              "DependenceNonUniformity" 425.000000 #
#    54.                           "RunEntropy" 425.000000 #
#    55.                   "MaximumProbability" 424.000000 #
#    56.                           "Complexity" 416.000000 #
#    57.        "SmallAreaLowGrayLevelEmphasis" 414.000000 #
#    58.                      "InverseVariance" 407.000000 #
#    59.   "GrayLevelNonUniformityNormalized.1" 406.000000 #
#    60.                           "SumEntropy" 406.000000 #
#    61.                    "ClusterProminence" 402.000000 #
#    62.          "RobustMeanAbsoluteDeviation" 402.000000 #
#    63.                    "SmallAreaEmphasis" 399.000000 #
#    64.                      "LongRunEmphasis" 398.000000 #
#    65.                  "GrayLevelVariance.2" 397.000000 #
#    66.        "ShortRunHighGrayLevelEmphasis" 397.000000 #
#    67.                "SizeZoneNonUniformity" 389.000000 #
#    68.             "GrayLevelNonUniformity.1" 388.000000 #
#    69.      "SizeZoneNonUniformityNormalized" 388.000000 #
#    70.              "LargeDependenceEmphasis" 386.000000 #
#    71.                           "Uniformity" 383.000000 #
#    72.                       "ZonePercentage" 383.000000 #
#    73.     "GrayLevelNonUniformityNormalized" 370.000000 #
#    74.              "SmallDependenceEmphasis" 366.000000 #
#    75.               "GrayLevelNonUniformity" 364.000000 #
#    76.                                   "Id" 358.000000
#    77.    "DependenceNonUniformityNormalized" 357.000000
#    78.                                  "Idm" 355.000000
#    79.                              "Entropy" 343.000000
#    80.                     "ShortRunEmphasis" 341.000000
#    81.                "MeanAbsoluteDeviation" 340.000000
#    82.                        "RunPercentage" 338.000000
#    83.                         "ZoneVariance" 338.000000
#    84.                          "JointEnergy" 337.000000
#    85.                    "GrayLevelVariance" 324.000000
#    86.     "RunLengthNonUniformityNormalized" 324.000000
#    87.                    "LargeAreaEmphasis" 319.000000
#    88.                           "SumSquares" 311.000000
#    89.               "RunLengthNonUniformity" 310.000000
#    90.                      "ClusterTendency" 306.000000
#    91.                         "JointEntropy" 278.000000
#    92.                             "Variance" 268.000000
#    93.                  "GrayLevelVariance.1" 263.000000
#
# Variable Importance: SUM_SCORE:
#     1.         "LongRunHighGrayLevelEmphasis" 185363.022416 ################
#     2.                         "90Percentile" 154445.203797 #############
#     3.                "HighGrayLevelEmphasis" 133106.105813 ###########
#     4.            "HighGrayLevelZoneEmphasis" 133073.956373 ###########
#     5.                      "Autocorrelation" 110955.288241 #########
#     6.                               "Energy" 110744.687492 #########
#     7.                      "RootMeanSquared" 99745.909314 ########
#     8. "LargeDependenceHighGrayLevelEmphasis" 95705.326050 ########
#     9.                          "TotalEnergy" 92527.605104 #######
#    10.             "HighGrayLevelRunEmphasis" 92497.312438 #######
#    11.                           "SumAverage" 78353.167943 ######
#    12.                                  "Idn" 70285.678559 #####
#    13.             "GrayLevelNonUniformity.2" 68091.349733 #####
#    14.                              "Maximum" 65419.252993 #####
#    15.                                 "Mean" 61681.890206 #####
#    16.                             "Busyness" 59393.792550 ####
#    17.                                 "Idmn" 56103.010489 ####
#    18.                               "Median" 51422.092723 ####
#    19.                         "JointAverage" 46671.205814 ###
#    20.                           "Coarseness" 45535.380352 ###
#    21.        "ShortRunHighGrayLevelEmphasis" 41319.928194 ###
#    22.       "SmallAreaHighGrayLevelEmphasis" 40636.555361 ###
#    23.       "LargeAreaHighGrayLevelEmphasis" 38067.936259 ##
#    24.         "ShortRunLowGrayLevelEmphasis" 30203.585451 ##
#    25.              "LowGrayLevelRunEmphasis" 27059.655022 ##
#    26.  "SmallDependenceLowGrayLevelEmphasis" 26150.740414 #
#    27.                             "Skewness" 25096.871756 #
#    28.             "LowGrayLevelZoneEmphasis" 24788.247574 #
#    29. "SmallDependenceHighGrayLevelEmphasis" 23782.986784 #
#    30.                    "DependenceEntropy" 23506.934458 #
#    31.                 "LowGrayLevelEmphasis" 21539.745066 #
#    32.                                 "Imc1" 21066.132583 #
#    33.              "DependenceNonUniformity" 20342.176614 #
#    34.                         "ClusterShade" 19935.017082 #
#    35.                      "InverseVariance" 19428.490149 #
#    36.                   "DependenceVariance" 17018.838442 #
#    37.                          "Correlation" 16805.386942 #
#    38.              "LargeDependenceEmphasis" 16790.055449 #
#    39.                       "ZonePercentage" 16466.355156 #
#    40.          "LongRunLowGrayLevelEmphasis" 15874.560331 #
#    41.                             "Strength" 15514.749507
#    42.    "DependenceNonUniformityNormalized" 15125.849622
#    43.                                 "Imc2" 14904.519950
#    44.        "LargeAreaLowGrayLevelEmphasis" 14633.783265
#    45.                         "10Percentile" 14504.507526
#    46.  "LargeDependenceLowGrayLevelEmphasis" 14483.069161
#    47.                           "Contrast.1" 14164.414159
#    48.                          "RunVariance" 14112.633270
#    49.              "SmallDependenceEmphasis" 13087.067698
#    50.                                  "MCC" 12551.011877
#    51.                        "RunPercentage" 12421.029218
#    52.                                "Range" 12346.297627
#    53.                      "LongRunEmphasis" 12292.918814
#    54.                   "MaximumProbability" 11635.715409
#    55.                             "Contrast" 11566.198326
#    56.                                  "Idm" 11355.226233
#    57.               "GrayLevelNonUniformity" 11041.971642
#    58.             "GrayLevelNonUniformity.1" 10853.068652
#    59.                   "DifferenceVariance" 10722.275790
#    60.                              "Minimum" 10694.866537
#    61.                           "SumEntropy" 10420.210979
#    62.                    "DifferenceAverage" 10239.819762
#    63.                             "Kurtosis" 9930.627154
#    64.                           "Uniformity" 9816.896556
#    65.                          "ZoneEntropy" 9385.234322
#    66.        "SmallAreaLowGrayLevelEmphasis" 9375.481143
#    67.                "SizeZoneNonUniformity" 9303.848443
#    68.                    "DifferenceEntropy" 9262.307718
#    69.                           "RunEntropy" 9097.339952
#    70.                                   "Id" 9057.703288
#    71.               "RunLengthNonUniformity" 8938.204190
#    72.   "GrayLevelNonUniformityNormalized.1" 8872.671255
#    73.                          "JointEnergy" 8685.998573
#    74.                              "Entropy" 8621.246934
#    75.                     "ShortRunEmphasis" 8117.985917
#    76.     "RunLengthNonUniformityNormalized" 7613.591910
#    77.      "SizeZoneNonUniformityNormalized" 7445.437860
#    78.                   "InterquartileRange" 7397.945963
#    79.                    "ClusterProminence" 7368.431545
#    80.                  "GrayLevelVariance.2" 7283.925960
#    81.     "GrayLevelNonUniformityNormalized" 7190.157639
#    82.                    "SmallAreaEmphasis" 6898.074401
#    83.                    "LargeAreaEmphasis" 6873.553800
#    84.                           "Complexity" 6854.280234
#    85.          "RobustMeanAbsoluteDeviation" 6757.497348
#    86.                         "ZoneVariance" 6750.913772
#    87.                    "GrayLevelVariance" 6160.308528
#    88.                "MeanAbsoluteDeviation" 6041.245988
#    89.                         "JointEntropy" 5615.211548
#    90.                           "SumSquares" 5379.551918
#    91.                      "ClusterTendency" 4952.085413
#    92.                  "GrayLevelVariance.1" 4528.194583
#    93.                             "Variance" 4245.816329
#
#
#
# Winner takes all: true
# Out-of-bag evaluation: accuracy:0.896633 logloss:0.275686
# Number of trees: 300
# Total number of nodes: 96304
#
# Number of nodes by tree:
# Count: 300 Average: 321.013 StdDev: 17.2248
# Min: 273 Max: 367 Ignored: 0
# ----------------------------------------------
# [ 273, 277)  2   0.67%   0.67%
# [ 277, 282)  2   0.67%   1.33%
# [ 282, 287)  1   0.33%   1.67%
# [ 287, 292) 14   4.67%   6.33% ###
# [ 292, 296)  5   1.67%   8.00% #
# [ 296, 301) 10   3.33%  11.33% ##
# [ 301, 306) 23   7.67%  19.00% #####
# [ 306, 311) 22   7.33%  26.33% #####
# [ 311, 315) 20   6.67%  33.00% ####
# [ 315, 320) 34  11.33%  44.33% ########
# [ 320, 325) 35  11.67%  56.00% ########
# [ 325, 330) 45  15.00%  71.00% ##########
# [ 330, 334) 24   8.00%  79.00% #####
# [ 334, 339) 19   6.33%  85.33% ####
# [ 339, 344) 17   5.67%  91.00% ####
# [ 344, 349) 10   3.33%  94.33% ##
# [ 349, 353)  6   2.00%  96.33% #
# [ 353, 358)  3   1.00%  97.33% #
# [ 358, 363)  5   1.67%  99.00% #
# [ 363, 367]  3   1.00% 100.00% #
#
# Depth by leafs:
# Count: 48302 Average: 9.33042 StdDev: 2.58616
# Min: 2 Max: 15 Ignored: 0
# ----------------------------------------------
# [  2,  3)   13   0.03%   0.03%
# [  3,  4)  272   0.56%   0.59%
# [  4,  5)  800   1.66%   2.25% #
# [  5,  6) 1944   4.02%   6.27% ###
# [  6,  7) 3763   7.79%  14.06% #####
# [  7,  8) 5398  11.18%  25.24% #######
# [  8,  9) 6723  13.92%  39.16% #########
# [  9, 10) 7255  15.02%  54.18% ##########
# [ 10, 11) 6572  13.61%  67.78% #########
# [ 11, 12) 5509  11.41%  79.19% ########
# [ 12, 13) 4112   8.51%  87.70% ######
# [ 13, 14) 2738   5.67%  93.37% ####
# [ 14, 15) 1829   3.79%  97.16% ###
# [ 15, 15] 1374   2.84% 100.00% ##
#
# Number of training obs by leaf:
# Count: 48302 Average: 86.5678 StdDev: 340.107
# Min: 5 Max: 5873 Ignored: 0
# ----------------------------------------------
# [    5,  298) 45528  94.26%  94.26% ##########
# [  298,  591)  1178   2.44%  96.70%
# [  591,  885)   440   0.91%  97.61%
# [  885, 1178)   268   0.55%  98.16%
# [ 1178, 1472)   176   0.36%  98.53%
# [ 1472, 1765)   153   0.32%  98.84%
# [ 1765, 2059)   148   0.31%  99.15%
# [ 2059, 2352)    99   0.20%  99.35%
# [ 2352, 2646)    76   0.16%  99.51%
# [ 2646, 2939)    58   0.12%  99.63%
# [ 2939, 3232)    39   0.08%  99.71%
# [ 3232, 3526)    37   0.08%  99.79%
# [ 3526, 3819)    40   0.08%  99.87%
# [ 3819, 4113)    26   0.05%  99.93%
# [ 4113, 4406)    21   0.04%  99.97%
# [ 4406, 4700)     5   0.01%  99.98%
# [ 4700, 4993)     8   0.02% 100.00%
# [ 4993, 5287)     1   0.00% 100.00%
# [ 5287, 5580)     0   0.00% 100.00%
# [ 5580, 5873]     1   0.00% 100.00%
#
# Attribute in nodes:
# 	1877 : Idn [NUMERICAL]
# 	1626 : Idmn [NUMERICAL]
# 	1045 : Skewness [NUMERICAL]
# 	1011 : GrayLevelNonUniformity.2 [NUMERICAL]
# 	994 : Maximum [NUMERICAL]
# 	913 : Busyness [NUMERICAL]
# 	906 : ClusterShade [NUMERICAL]
# 	901 : LargeDependenceHighGrayLevelEmphasis [NUMERICAL]
# 	894 : Coarseness [NUMERICAL]
# 	821 : Median [NUMERICAL]
# 	805 : LongRunHighGrayLevelEmphasis [NUMERICAL]
# 	696 : 90Percentile [NUMERICAL]
# 	692 : SmallAreaHighGrayLevelEmphasis [NUMERICAL]
# 	678 : Correlation [NUMERICAL]
# 	650 : DependenceEntropy [NUMERICAL]
# 	643 : Imc1 [NUMERICAL]
# 	632 : Contrast.1 [NUMERICAL]
# 	618 : Kurtosis [NUMERICAL]
# 	607 : Strength [NUMERICAL]
# 	593 : Autocorrelation [NUMERICAL]
# 	589 : HighGrayLevelZoneEmphasis [NUMERICAL]
# 	587 : Range [NUMERICAL]
# 	566 : LargeAreaHighGrayLevelEmphasis [NUMERICAL]
# 	536 : MCC [NUMERICAL]
# 	533 : Imc2 [NUMERICAL]
# 	520 : Contrast [NUMERICAL]
# 	518 : SmallDependenceHighGrayLevelEmphasis [NUMERICAL]
# 	518 : JointAverage [NUMERICAL]
# 	513 : DifferenceVariance [NUMERICAL]
# 	504 : RootMeanSquared [NUMERICAL]
# 	501 : SmallDependenceLowGrayLevelEmphasis [NUMERICAL]
# 	495 : Energy [NUMERICAL]
# 	494 : TotalEnergy [NUMERICAL]
# 	485 : HighGrayLevelEmphasis [NUMERICAL]
# 	481 : DependenceVariance [NUMERICAL]
# 	475 : SumAverage [NUMERICAL]
# 	467 : RunVariance [NUMERICAL]
# 	466 : LowGrayLevelZoneEmphasis [NUMERICAL]
# 	461 : LargeDependenceLowGrayLevelEmphasis [NUMERICAL]
# 	460 : DifferenceAverage [NUMERICAL]
# 	458 : 10Percentile [NUMERICAL]
# 	449 : HighGrayLevelRunEmphasis [NUMERICAL]
# 	447 : DifferenceEntropy [NUMERICAL]
# 	442 : Mean [NUMERICAL]
# 	442 : LowGrayLevelEmphasis [NUMERICAL]
# 	441 : InterquartileRange [NUMERICAL]
# 	438 : LowGrayLevelRunEmphasis [NUMERICAL]
# 	436 : Minimum [NUMERICAL]
# 	435 : ZoneEntropy [NUMERICAL]
# 	435 : LargeAreaLowGrayLevelEmphasis [NUMERICAL]
# 	432 : ShortRunLowGrayLevelEmphasis [NUMERICAL]
# 	431 : LongRunLowGrayLevelEmphasis [NUMERICAL]
# 	425 : RunEntropy [NUMERICAL]
# 	425 : DependenceNonUniformity [NUMERICAL]
# 	424 : MaximumProbability [NUMERICAL]
# 	416 : Complexity [NUMERICAL]
# 	414 : SmallAreaLowGrayLevelEmphasis [NUMERICAL]
# 	407 : InverseVariance [NUMERICAL]
# 	406 : SumEntropy [NUMERICAL]
# 	406 : GrayLevelNonUniformityNormalized.1 [NUMERICAL]
# 	402 : RobustMeanAbsoluteDeviation [NUMERICAL]
# 	402 : ClusterProminence [NUMERICAL]
# 	399 : SmallAreaEmphasis [NUMERICAL]
# 	398 : LongRunEmphasis [NUMERICAL]
# 	397 : ShortRunHighGrayLevelEmphasis [NUMERICAL]
# 	397 : GrayLevelVariance.2 [NUMERICAL]
# 	389 : SizeZoneNonUniformity [NUMERICAL]
# 	388 : SizeZoneNonUniformityNormalized [NUMERICAL]
# 	388 : GrayLevelNonUniformity.1 [NUMERICAL]
# 	386 : LargeDependenceEmphasis [NUMERICAL]
# 	383 : ZonePercentage [NUMERICAL]
# 	383 : Uniformity [NUMERICAL]
# 	370 : GrayLevelNonUniformityNormalized [NUMERICAL]
# 	366 : SmallDependenceEmphasis [NUMERICAL]
# 	364 : GrayLevelNonUniformity [NUMERICAL]
# 	358 : Id [NUMERICAL]
# 	357 : DependenceNonUniformityNormalized [NUMERICAL]
# 	355 : Idm [NUMERICAL]
# 	343 : Entropy [NUMERICAL]
# 	341 : ShortRunEmphasis [NUMERICAL]
# 	340 : MeanAbsoluteDeviation [NUMERICAL]
# 	338 : ZoneVariance [NUMERICAL]
# 	338 : RunPercentage [NUMERICAL]
# 	337 : JointEnergy [NUMERICAL]
# 	324 : RunLengthNonUniformityNormalized [NUMERICAL]
# 	324 : GrayLevelVariance [NUMERICAL]
# 	319 : LargeAreaEmphasis [NUMERICAL]
# 	311 : SumSquares [NUMERICAL]
# 	310 : RunLengthNonUniformity [NUMERICAL]
# 	306 : ClusterTendency [NUMERICAL]
# 	278 : JointEntropy [NUMERICAL]
# 	268 : Variance [NUMERICAL]
# 	263 : GrayLevelVariance.1 [NUMERICAL]
#
# Attribute in nodes with depth <= 0:
# 	31 : 90Percentile [NUMERICAL]
# 	29 : LongRunHighGrayLevelEmphasis [NUMERICAL]
# 	29 : HighGrayLevelZoneEmphasis [NUMERICAL]
# 	27 : HighGrayLevelEmphasis [NUMERICAL]
# 	22 : Energy [NUMERICAL]
# 	19 : RootMeanSquared [NUMERICAL]
# 	19 : Autocorrelation [NUMERICAL]
# 	18 : TotalEnergy [NUMERICAL]
# 	18 : HighGrayLevelRunEmphasis [NUMERICAL]
# 	15 : SumAverage [NUMERICAL]
# 	10 : Mean [NUMERICAL]
# 	7 : ShortRunHighGrayLevelEmphasis [NUMERICAL]
# 	7 : Maximum [NUMERICAL]
# 	6 : ShortRunLowGrayLevelEmphasis [NUMERICAL]
# 	6 : JointAverage [NUMERICAL]
# 	5 : SmallAreaHighGrayLevelEmphasis [NUMERICAL]
# 	4 : Median [NUMERICAL]
# 	4 : Busyness [NUMERICAL]
# 	3 : LowGrayLevelZoneEmphasis [NUMERICAL]
# 	3 : LowGrayLevelRunEmphasis [NUMERICAL]
# 	3 : LargeDependenceHighGrayLevelEmphasis [NUMERICAL]
# 	2 : SmallDependenceLowGrayLevelEmphasis [NUMERICAL]
# 	2 : SmallDependenceHighGrayLevelEmphasis [NUMERICAL]
# 	2 : LowGrayLevelEmphasis [NUMERICAL]
# 	1 : SumEntropy [NUMERICAL]
# 	1 : Minimum [NUMERICAL]
# 	1 : MCC [NUMERICAL]
# 	1 : LongRunLowGrayLevelEmphasis [NUMERICAL]
# 	1 : LargeAreaLowGrayLevelEmphasis [NUMERICAL]
# 	1 : JointEntropy [NUMERICAL]
# 	1 : GrayLevelNonUniformity [NUMERICAL]
# 	1 : DependenceEntropy [NUMERICAL]
# 	1 : 10Percentile [NUMERICAL]
#
# Attribute in nodes with depth <= 1:
# 	93 : LongRunHighGrayLevelEmphasis [NUMERICAL]
# 	59 : HighGrayLevelEmphasis [NUMERICAL]
# 	59 : Autocorrelation [NUMERICAL]
# 	48 : Energy [NUMERICAL]
# 	45 : 90Percentile [NUMERICAL]
# 	43 : HighGrayLevelZoneEmphasis [NUMERICAL]
# 	42 : HighGrayLevelRunEmphasis [NUMERICAL]
# 	40 : RootMeanSquared [NUMERICAL]
# 	38 : TotalEnergy [NUMERICAL]
# 	33 : LargeDependenceHighGrayLevelEmphasis [NUMERICAL]
# 	32 : SumAverage [NUMERICAL]
# 	32 : Mean [NUMERICAL]
# 	24 : Median [NUMERICAL]
# 	23 : Coarseness [NUMERICAL]
# 	22 : SmallDependenceLowGrayLevelEmphasis [NUMERICAL]
# 	22 : JointAverage [NUMERICAL]
# 	20 : GrayLevelNonUniformity.2 [NUMERICAL]
# 	16 : LargeAreaHighGrayLevelEmphasis [NUMERICAL]
# 	15 : SmallAreaHighGrayLevelEmphasis [NUMERICAL]
# 	15 : Busyness [NUMERICAL]
# 	14 : ShortRunHighGrayLevelEmphasis [NUMERICAL]
# 	12 : ShortRunLowGrayLevelEmphasis [NUMERICAL]
# 	12 : LowGrayLevelRunEmphasis [NUMERICAL]
# 	11 : LowGrayLevelZoneEmphasis [NUMERICAL]
# 	10 : ZonePercentage [NUMERICAL]
# 	10 : Maximum [NUMERICAL]
# 	10 : InverseVariance [NUMERICAL]
# 	10 : DependenceNonUniformity [NUMERICAL]
# 	8 : SmallDependenceEmphasis [NUMERICAL]
# 	8 : DependenceNonUniformityNormalized [NUMERICAL]
# 	7 : LowGrayLevelEmphasis [NUMERICAL]
# 	7 : 10Percentile [NUMERICAL]
# 	5 : LongRunLowGrayLevelEmphasis [NUMERICAL]
# 	5 : LargeDependenceLowGrayLevelEmphasis [NUMERICAL]
# 	4 : SmallDependenceHighGrayLevelEmphasis [NUMERICAL]
# 	4 : MaximumProbability [NUMERICAL]
# 	4 : LargeAreaLowGrayLevelEmphasis [NUMERICAL]
# 	4 : Contrast.1 [NUMERICAL]
# 	3 : SizeZoneNonUniformity [NUMERICAL]
# 	3 : RunLengthNonUniformityNormalized [NUMERICAL]
# 	2 : SmallAreaLowGrayLevelEmphasis [NUMERICAL]
# 	2 : RunPercentage [NUMERICAL]
# 	2 : LargeDependenceEmphasis [NUMERICAL]
# 	2 : Id [NUMERICAL]
# 	2 : GrayLevelNonUniformity.1 [NUMERICAL]
# 	2 : Entropy [NUMERICAL]
# 	2 : DependenceEntropy [NUMERICAL]
# 	1 : SumEntropy [NUMERICAL]
# 	1 : SmallAreaEmphasis [NUMERICAL]
# 	1 : SizeZoneNonUniformityNormalized [NUMERICAL]
# 	1 : RunVariance [NUMERICAL]
# 	1 : Minimum [NUMERICAL]
# 	1 : MCC [NUMERICAL]
# 	1 : LongRunEmphasis [NUMERICAL]
# 	1 : JointEntropy [NUMERICAL]
# 	1 : InterquartileRange [NUMERICAL]
# 	1 : Idm [NUMERICAL]
# 	1 : GrayLevelNonUniformity [NUMERICAL]
# 	1 : DifferenceEntropy [NUMERICAL]
# 	1 : DifferenceAverage [NUMERICAL]
# 	1 : ClusterProminence [NUMERICAL]
#
# Attribute in nodes with depth <= 2:
# 	150 : LongRunHighGrayLevelEmphasis [NUMERICAL]
# 	106 : Autocorrelation [NUMERICAL]
# 	98 : LargeDependenceHighGrayLevelEmphasis [NUMERICAL]
# 	83 : Median [NUMERICAL]
# 	83 : HighGrayLevelEmphasis [NUMERICAL]
# 	78 : Energy [NUMERICAL]
# 	74 : GrayLevelNonUniformity.2 [NUMERICAL]
# 	68 : RootMeanSquared [NUMERICAL]
# 	65 : SumAverage [NUMERICAL]
# 	64 : 90Percentile [NUMERICAL]
# 	62 : Busyness [NUMERICAL]
# 	61 : TotalEnergy [NUMERICAL]
# 	61 : Coarseness [NUMERICAL]
# 	58 : HighGrayLevelRunEmphasis [NUMERICAL]
# 	57 : JointAverage [NUMERICAL]
# 	52 : Mean [NUMERICAL]
# 	51 : HighGrayLevelZoneEmphasis [NUMERICAL]
# 	45 : LargeAreaHighGrayLevelEmphasis [NUMERICAL]
# 	33 : ShortRunHighGrayLevelEmphasis [NUMERICAL]
# 	33 : Maximum [NUMERICAL]
# 	31 : SmallDependenceLowGrayLevelEmphasis [NUMERICAL]
# 	30 : LowGrayLevelRunEmphasis [NUMERICAL]
# 	30 : LowGrayLevelEmphasis [NUMERICAL]
# 	29 : Correlation [NUMERICAL]
# 	28 : DependenceEntropy [NUMERICAL]
# 	24 : Skewness [NUMERICAL]
# 	23 : ShortRunLowGrayLevelEmphasis [NUMERICAL]
# 	23 : LargeDependenceEmphasis [NUMERICAL]
# 	23 : DependenceNonUniformity [NUMERICAL]
# 	21 : ZonePercentage [NUMERICAL]
# 	21 : SmallAreaHighGrayLevelEmphasis [NUMERICAL]
# 	20 : LowGrayLevelZoneEmphasis [NUMERICAL]
# 	19 : InverseVariance [NUMERICAL]
# 	18 : Imc1 [NUMERICAL]
# 	18 : DependenceNonUniformityNormalized [NUMERICAL]
# 	17 : LongRunLowGrayLevelEmphasis [NUMERICAL]
# 	15 : SmallDependenceHighGrayLevelEmphasis [NUMERICAL]
# 	15 : ClusterShade [NUMERICAL]
# 	14 : SmallDependenceEmphasis [NUMERICAL]
# 	14 : RunPercentage [NUMERICAL]
# 	14 : LargeDependenceLowGrayLevelEmphasis [NUMERICAL]
# 	14 : Imc2 [NUMERICAL]
# 	13 : LargeAreaLowGrayLevelEmphasis [NUMERICAL]
# 	13 : 10Percentile [NUMERICAL]
# 	12 : Idn [NUMERICAL]
# 	12 : Idm [NUMERICAL]
# 	11 : JointEnergy [NUMERICAL]
# 	11 : DependenceVariance [NUMERICAL]
# 	10 : GrayLevelNonUniformity.1 [NUMERICAL]
# 	9 : MaximumProbability [NUMERICAL]
# 	9 : LongRunEmphasis [NUMERICAL]
# 	9 : GrayLevelNonUniformity [NUMERICAL]
# 	8 : Minimum [NUMERICAL]
# 	8 : Idmn [NUMERICAL]
# 	7 : Strength [NUMERICAL]
# 	7 : SmallAreaLowGrayLevelEmphasis [NUMERICAL]
# 	7 : RunVariance [NUMERICAL]
# 	7 : MCC [NUMERICAL]
# 	6 : Uniformity [NUMERICAL]
# 	6 : ShortRunEmphasis [NUMERICAL]
# 	6 : Contrast.1 [NUMERICAL]
# 	5 : SizeZoneNonUniformity [NUMERICAL]
# 	5 : RunLengthNonUniformity [NUMERICAL]
# 	5 : DifferenceVariance [NUMERICAL]
# 	4 : ZoneEntropy [NUMERICAL]
# 	4 : RunLengthNonUniformityNormalized [NUMERICAL]
# 	4 : Id [NUMERICAL]
# 	4 : GrayLevelNonUniformityNormalized [NUMERICAL]
# 	4 : Entropy [NUMERICAL]
# 	4 : DifferenceEntropy [NUMERICAL]
# 	3 : SmallAreaEmphasis [NUMERICAL]
# 	3 : SizeZoneNonUniformityNormalized [NUMERICAL]
# 	3 : RunEntropy [NUMERICAL]
# 	3 : Kurtosis [NUMERICAL]
# 	3 : DifferenceAverage [NUMERICAL]
# 	3 : Contrast [NUMERICAL]
# 	2 : SumEntropy [NUMERICAL]
# 	2 : LargeAreaEmphasis [NUMERICAL]
# 	2 : JointEntropy [NUMERICAL]
# 	2 : InterquartileRange [NUMERICAL]
# 	1 : ZoneVariance [NUMERICAL]
# 	1 : SumSquares [NUMERICAL]
# 	1 : RobustMeanAbsoluteDeviation [NUMERICAL]
# 	1 : MeanAbsoluteDeviation [NUMERICAL]
# 	1 : GrayLevelNonUniformityNormalized.1 [NUMERICAL]
# 	1 : Complexity [NUMERICAL]
# 	1 : ClusterTendency [NUMERICAL]
# 	1 : ClusterProminence [NUMERICAL]
#
# Attribute in nodes with depth <= 3:
# 	200 : LongRunHighGrayLevelEmphasis [NUMERICAL]
# 	161 : LargeDependenceHighGrayLevelEmphasis [NUMERICAL]
# 	150 : GrayLevelNonUniformity.2 [NUMERICAL]
# 	142 : Autocorrelation [NUMERICAL]
# 	134 : Median [NUMERICAL]
# 	134 : Busyness [NUMERICAL]
# 	121 : Coarseness [NUMERICAL]
# 	110 : 90Percentile [NUMERICAL]
# 	100 : RootMeanSquared [NUMERICAL]
# 	100 : HighGrayLevelEmphasis [NUMERICAL]
# 	98 : SumAverage [NUMERICAL]
# 	94 : Energy [NUMERICAL]
# 	90 : TotalEnergy [NUMERICAL]
# 	87 : JointAverage [NUMERICAL]
# 	85 : Maximum [NUMERICAL]
# 	83 : HighGrayLevelRunEmphasis [NUMERICAL]
# 	80 : Mean [NUMERICAL]
# 	79 : LargeAreaHighGrayLevelEmphasis [NUMERICAL]
# 	78 : Skewness [NUMERICAL]
# 	71 : HighGrayLevelZoneEmphasis [NUMERICAL]
# 	71 : DependenceEntropy [NUMERICAL]
# 	71 : Correlation [NUMERICAL]
# 	63 : Imc1 [NUMERICAL]
# 	63 : Idn [NUMERICAL]
# 	61 : SmallDependenceLowGrayLevelEmphasis [NUMERICAL]
# 	58 : LowGrayLevelRunEmphasis [NUMERICAL]
# 	56 : ClusterShade [NUMERICAL]
# 	54 : Idmn [NUMERICAL]
# 	53 : ShortRunHighGrayLevelEmphasis [NUMERICAL]
# 	53 : InverseVariance [NUMERICAL]
# 	49 : LowGrayLevelEmphasis [NUMERICAL]
# 	45 : Imc2 [NUMERICAL]
# 	44 : DependenceNonUniformity [NUMERICAL]
# 	43 : LargeDependenceEmphasis [NUMERICAL]
# 	42 : SmallAreaHighGrayLevelEmphasis [NUMERICAL]
# 	41 : ShortRunLowGrayLevelEmphasis [NUMERICAL]
# 	39 : LongRunLowGrayLevelEmphasis [NUMERICAL]
# 	37 : LowGrayLevelZoneEmphasis [NUMERICAL]
# 	36 : Minimum [NUMERICAL]
# 	35 : RunVariance [NUMERICAL]
# 	33 : ZonePercentage [NUMERICAL]
# 	33 : Strength [NUMERICAL]
# 	33 : SmallDependenceHighGrayLevelEmphasis [NUMERICAL]
# 	31 : SmallDependenceEmphasis [NUMERICAL]
# 	30 : LargeDependenceLowGrayLevelEmphasis [NUMERICAL]
# 	29 : Uniformity [NUMERICAL]
# 	28 : GrayLevelNonUniformity.1 [NUMERICAL]
# 	28 : DependenceVariance [NUMERICAL]
# 	26 : MCC [NUMERICAL]
# 	26 : LongRunEmphasis [NUMERICAL]
# 	26 : Idm [NUMERICAL]
# 	26 : GrayLevelNonUniformity [NUMERICAL]
# 	25 : SumEntropy [NUMERICAL]
# 	25 : RunPercentage [NUMERICAL]
# 	25 : MaximumProbability [NUMERICAL]
# 	25 : LargeAreaLowGrayLevelEmphasis [NUMERICAL]
# 	25 : DifferenceVariance [NUMERICAL]
# 	25 : DependenceNonUniformityNormalized [NUMERICAL]
# 	23 : 10Percentile [NUMERICAL]
# 	22 : Entropy [NUMERICAL]
# 	21 : RunEntropy [NUMERICAL]
# 	21 : JointEnergy [NUMERICAL]
# 	20 : Kurtosis [NUMERICAL]
# 	19 : SmallAreaLowGrayLevelEmphasis [NUMERICAL]
# 	19 : SizeZoneNonUniformity [NUMERICAL]
# 	19 : DifferenceEntropy [NUMERICAL]
# 	18 : ZoneEntropy [NUMERICAL]
# 	18 : GrayLevelNonUniformityNormalized.1 [NUMERICAL]
# 	18 : GrayLevelNonUniformityNormalized [NUMERICAL]
# 	18 : Contrast.1 [NUMERICAL]
# 	17 : RunLengthNonUniformity [NUMERICAL]
# 	17 : DifferenceAverage [NUMERICAL]
# 	17 : Contrast [NUMERICAL]
# 	15 : SizeZoneNonUniformityNormalized [NUMERICAL]
# 	15 : ShortRunEmphasis [NUMERICAL]
# 	15 : GrayLevelVariance.2 [NUMERICAL]
# 	14 : Range [NUMERICAL]
# 	14 : Id [NUMERICAL]
# 	14 : ClusterProminence [NUMERICAL]
# 	13 : InterquartileRange [NUMERICAL]
# 	11 : RunLengthNonUniformityNormalized [NUMERICAL]
# 	10 : SmallAreaEmphasis [NUMERICAL]
# 	10 : GrayLevelVariance [NUMERICAL]
# 	9 : SumSquares [NUMERICAL]
# 	9 : Complexity [NUMERICAL]
# 	8 : JointEntropy [NUMERICAL]
# 	7 : GrayLevelVariance.1 [NUMERICAL]
# 	6 : LargeAreaEmphasis [NUMERICAL]
# 	6 : ClusterTendency [NUMERICAL]
# 	5 : MeanAbsoluteDeviation [NUMERICAL]
# 	4 : ZoneVariance [NUMERICAL]
# 	4 : Variance [NUMERICAL]
# 	3 : RobustMeanAbsoluteDeviation [NUMERICAL]
#
# Attribute in nodes with depth <= 5:
# 	401 : Idn [NUMERICAL]
# 	382 : Idmn [NUMERICAL]
# 	364 : GrayLevelNonUniformity.2 [NUMERICAL]
# 	337 : LongRunHighGrayLevelEmphasis [NUMERICAL]
# 	320 : Coarseness [NUMERICAL]
# 	313 : Skewness [NUMERICAL]
# 	313 : Busyness [NUMERICAL]
# 	310 : LargeDependenceHighGrayLevelEmphasis [NUMERICAL]
# 	298 : Maximum [NUMERICAL]
# 	278 : Median [NUMERICAL]
# 	243 : ClusterShade [NUMERICAL]
# 	239 : Autocorrelation [NUMERICAL]
# 	237 : 90Percentile [NUMERICAL]
# 	210 : DependenceEntropy [NUMERICAL]
# 	188 : LargeAreaHighGrayLevelEmphasis [NUMERICAL]
# 	184 : Imc1 [NUMERICAL]
# 	184 : HighGrayLevelEmphasis [NUMERICAL]
# 	184 : Energy [NUMERICAL]
# 	182 : JointAverage [NUMERICAL]
# 	178 : RootMeanSquared [NUMERICAL]
# 	174 : HighGrayLevelZoneEmphasis [NUMERICAL]
# 	174 : HighGrayLevelRunEmphasis [NUMERICAL]
# 	173 : SmallAreaHighGrayLevelEmphasis [NUMERICAL]
# 	172 : Correlation [NUMERICAL]
# 	170 : SumAverage [NUMERICAL]
# 	166 : TotalEnergy [NUMERICAL]
# 	163 : Mean [NUMERICAL]
# 	142 : SmallDependenceLowGrayLevelEmphasis [NUMERICAL]
# 	139 : LowGrayLevelRunEmphasis [NUMERICAL]
# 	138 : LowGrayLevelZoneEmphasis [NUMERICAL]
# 	134 : Imc2 [NUMERICAL]
# 	130 : SmallDependenceHighGrayLevelEmphasis [NUMERICAL]
# 	128 : Strength [NUMERICAL]
# 	127 : RunVariance [NUMERICAL]
# 	126 : LowGrayLevelEmphasis [NUMERICAL]
# 	125 : Kurtosis [NUMERICAL]
# 	123 : InverseVariance [NUMERICAL]
# 	119 : DependenceNonUniformity [NUMERICAL]
# 	115 : ShortRunLowGrayLevelEmphasis [NUMERICAL]
# 	113 : LongRunLowGrayLevelEmphasis [NUMERICAL]
# 	113 : DifferenceVariance [NUMERICAL]
# 	110 : ShortRunHighGrayLevelEmphasis [NUMERICAL]
# 	109 : MCC [NUMERICAL]
# 	108 : LargeAreaLowGrayLevelEmphasis [NUMERICAL]
# 	108 : Contrast.1 [NUMERICAL]
# 	108 : Contrast [NUMERICAL]
# 	107 : Range [NUMERICAL]
# 	104 : Minimum [NUMERICAL]
# 	104 : LargeDependenceEmphasis [NUMERICAL]
# 	104 : GrayLevelNonUniformity.1 [NUMERICAL]
# 	102 : DependenceVariance [NUMERICAL]
# 	98 : GrayLevelNonUniformity [NUMERICAL]
# 	97 : LargeDependenceLowGrayLevelEmphasis [NUMERICAL]
# 	96 : LongRunEmphasis [NUMERICAL]
# 	94 : Uniformity [NUMERICAL]
# 	94 : SmallDependenceEmphasis [NUMERICAL]
# 	90 : SumEntropy [NUMERICAL]
# 	87 : RunPercentage [NUMERICAL]
# 	87 : RunEntropy [NUMERICAL]
# 	87 : MaximumProbability [NUMERICAL]
# 	87 : 10Percentile [NUMERICAL]
# 	86 : SmallAreaLowGrayLevelEmphasis [NUMERICAL]
# 	85 : DifferenceAverage [NUMERICAL]
# 	85 : Complexity [NUMERICAL]
# 	84 : GrayLevelVariance.2 [NUMERICAL]
# 	84 : GrayLevelNonUniformityNormalized [NUMERICAL]
# 	82 : InterquartileRange [NUMERICAL]
# 	81 : Entropy [NUMERICAL]
# 	81 : DifferenceEntropy [NUMERICAL]
# 	80 : ZonePercentage [NUMERICAL]
# 	79 : GrayLevelNonUniformityNormalized.1 [NUMERICAL]
# 	77 : DependenceNonUniformityNormalized [NUMERICAL]
# 	76 : ZoneEntropy [NUMERICAL]
# 	75 : Id [NUMERICAL]
# 	75 : ClusterProminence [NUMERICAL]
# 	73 : SmallAreaEmphasis [NUMERICAL]
# 	72 : Idm [NUMERICAL]
# 	69 : SizeZoneNonUniformity [NUMERICAL]
# 	68 : RunLengthNonUniformity [NUMERICAL]
# 	68 : JointEnergy [NUMERICAL]
# 	64 : ZoneVariance [NUMERICAL]
# 	64 : RunLengthNonUniformityNormalized [NUMERICAL]
# 	63 : LargeAreaEmphasis [NUMERICAL]
# 	61 : SizeZoneNonUniformityNormalized [NUMERICAL]
# 	60 : ShortRunEmphasis [NUMERICAL]
# 	59 : ClusterTendency [NUMERICAL]
# 	55 : GrayLevelVariance [NUMERICAL]
# 	50 : MeanAbsoluteDeviation [NUMERICAL]
# 	49 : JointEntropy [NUMERICAL]
# 	47 : RobustMeanAbsoluteDeviation [NUMERICAL]
# 	44 : SumSquares [NUMERICAL]
# 	39 : GrayLevelVariance.1 [NUMERICAL]
# 	32 : Variance [NUMERICAL]
#
# Condition type in nodes:
# 	48002 : HigherCondition
# Condition type in nodes with depth <= 0:
# 	300 : HigherCondition
# Condition type in nodes with depth <= 1:
# 	900 : HigherCondition
# Condition type in nodes with depth <= 2:
# 	2087 : HigherCondition
# Condition type in nodes with depth <= 3:
# 	4189 : HigherCondition
# Condition type in nodes with depth <= 5:
# 	12457 : HigherCondition
# Node format: NOT_SET
#
# Training OOB:
# 	trees: 1, Out-of-bag evaluation: accuracy:0.864828 logloss:4.87209
# 	trees: 11, Out-of-bag evaluation: accuracy:0.86867 logloss:1.74559
# 	trees: 21, Out-of-bag evaluation: accuracy:0.886443 logloss:0.89019
# 	trees: 31, Out-of-bag evaluation: accuracy:0.882916 logloss:0.72239
# 	trees: 41, Out-of-bag evaluation: accuracy:0.889215 logloss:0.625841
# 	trees: 51, Out-of-bag evaluation: accuracy:0.882955 logloss:0.516505
# 	trees: 61, Out-of-bag evaluation: accuracy:0.88828 logloss:0.461121
# 	trees: 71, Out-of-bag evaluation: accuracy:0.89061 logloss:0.442224
# 	trees: 81, Out-of-bag evaluation: accuracy:0.891269 logloss:0.420083
# 	trees: 91, Out-of-bag evaluation: accuracy:0.893369 logloss:0.381611
# 	trees: 101, Out-of-bag evaluation: accuracy:0.894182 logloss:0.329696
# 	trees: 111, Out-of-bag evaluation: accuracy:0.896127 logloss:0.32815
# 	trees: 121, Out-of-bag evaluation: accuracy:0.896787 logloss:0.31096
# 	trees: 131, Out-of-bag evaluation: accuracy:0.89566 logloss:0.310001
# 	trees: 141, Out-of-bag evaluation: accuracy:0.898419 logloss:0.309201
# 	trees: 151, Out-of-bag evaluation: accuracy:0.898265 logloss:0.291232
# 	trees: 161, Out-of-bag evaluation: accuracy:0.897254 logloss:0.274582
# 	trees: 171, Out-of-bag evaluation: accuracy:0.898457 logloss:0.274427
# 	trees: 181, Out-of-bag evaluation: accuracy:0.899821 logloss:0.274808
# 	trees: 191, Out-of-bag evaluation: accuracy:0.897292 logloss:0.275161
# 	trees: 201, Out-of-bag evaluation: accuracy:0.897254 logloss:0.274828
# 	trees: 211, Out-of-bag evaluation: accuracy:0.897254 logloss:0.275102
# 	trees: 221, Out-of-bag evaluation: accuracy:0.897875 logloss:0.275032
# 	trees: 231, Out-of-bag evaluation: accuracy:0.896748 logloss:0.274679
# 	trees: 241, Out-of-bag evaluation: accuracy:0.896243 logloss:0.274679
# 	trees: 251, Out-of-bag evaluation: accuracy:0.896166 logloss:0.274439
# 	trees: 261, Out-of-bag evaluation: accuracy:0.897798 logloss:0.274553
# 	trees: 271, Out-of-bag evaluation: accuracy:0.897721 logloss:0.274595
# 	trees: 281, Out-of-bag evaluation: accuracy:0.898886 logloss:0.274486
# 	trees: 291, Out-of-bag evaluation: accuracy:0.897139 logloss:0.274872
# 	trees: 300, Out-of-bag evaluation: accuracy:0.896633 logloss:0.275686

# %%
# Model features
model.make_inspector().features()
# Out:
# ["10Percentile" (1; #0),
#  "90Percentile" (1; #1),
#  "Autocorrelation" (1; #2),
#  "Busyness" (1; #3),
#  "ClusterProminence" (1; #4),
#  "ClusterShade" (1; #5),
#  "ClusterTendency" (1; #6),
#  "Coarseness" (1; #7),
#  "Complexity" (1; #8),
#  "Contrast" (1; #9),
#  "Contrast.1" (1; #10),
#  "Correlation" (1; #11),
#  "DependenceEntropy" (1; #12),
#  "DependenceNonUniformity" (1; #13),
#  "DependenceNonUniformityNormalized" (1; #14),
#  "DependenceVariance" (1; #15),
#  "DifferenceAverage" (1; #16),
#  "DifferenceEntropy" (1; #17),
#  "DifferenceVariance" (1; #18),
#  "Energy" (1; #19),
#  "Entropy" (1; #20),
#  "GrayLevelNonUniformity" (1; #21),
#  "GrayLevelNonUniformity.1" (1; #22),
#  "GrayLevelNonUniformity.2" (1; #23),
#  "GrayLevelNonUniformityNormalized" (1; #24),
#  "GrayLevelNonUniformityNormalized.1" (1; #25),
#  "GrayLevelVariance" (1; #26),
#  "GrayLevelVariance.1" (1; #27),
#  "GrayLevelVariance.2" (1; #28),
#  "HighGrayLevelEmphasis" (1; #29),
#  "HighGrayLevelRunEmphasis" (1; #30),
#  "HighGrayLevelZoneEmphasis" (1; #31),
#  "Id" (1; #32),
#  "Idm" (1; #33),
#  "Idmn" (1; #34),
#  "Idn" (1; #35),
#  "Imc1" (1; #36),
#  "Imc2" (1; #37),
#  "InterquartileRange" (1; #38),
#  "InverseVariance" (1; #39),
#  "JointAverage" (1; #40),
#  "JointEnergy" (1; #41),
#  "JointEntropy" (1; #42),
#  "Kurtosis" (1; #43),
#  "LargeAreaEmphasis" (1; #44),
#  "LargeAreaHighGrayLevelEmphasis" (1; #45),
#  "LargeAreaLowGrayLevelEmphasis" (1; #46),
#  "LargeDependenceEmphasis" (1; #47),
#  "LargeDependenceHighGrayLevelEmphasis" (1; #48),
#  "LargeDependenceLowGrayLevelEmphasis" (1; #49),
#  "LongRunEmphasis" (1; #50),
#  "LongRunHighGrayLevelEmphasis" (1; #51),
#  "LongRunLowGrayLevelEmphasis" (1; #52),
#  "LowGrayLevelEmphasis" (1; #53),
#  "LowGrayLevelRunEmphasis" (1; #54),
#  "LowGrayLevelZoneEmphasis" (1; #55),
#  "MCC" (1; #56),
#  "Maximum" (1; #57),
#  "MaximumProbability" (1; #58),
#  "Mean" (1; #59),
#  "MeanAbsoluteDeviation" (1; #60),
#  "Median" (1; #61),
#  "Minimum" (1; #62),
#  "Range" (1; #63),
#  "RobustMeanAbsoluteDeviation" (1; #64),
#  "RootMeanSquared" (1; #65),
#  "RunEntropy" (1; #66),
#  "RunLengthNonUniformity" (1; #67),
#  "RunLengthNonUniformityNormalized" (1; #68),
#  "RunPercentage" (1; #69),
#  "RunVariance" (1; #70),
#  "ShortRunEmphasis" (1; #71),
#  "ShortRunHighGrayLevelEmphasis" (1; #72),
#  "ShortRunLowGrayLevelEmphasis" (1; #73),
#  "SizeZoneNonUniformity" (1; #74),
#  "SizeZoneNonUniformityNormalized" (1; #75),
#  "Skewness" (1; #76),
#  "SmallAreaEmphasis" (1; #77),
#  "SmallAreaHighGrayLevelEmphasis" (1; #78),
#  "SmallAreaLowGrayLevelEmphasis" (1; #79),
#  "SmallDependenceEmphasis" (1; #80),
#  "SmallDependenceHighGrayLevelEmphasis" (1; #81),
#  "SmallDependenceLowGrayLevelEmphasis" (1; #82),
#  "Strength" (1; #83),
#  "SumAverage" (1; #84),
#  "SumEntropy" (1; #85),
#  "SumSquares" (1; #86),
#  "TotalEnergy" (1; #87),
#  "Uniformity" (1; #88),
#  "Variance" (1; #89),
#  "ZoneEntropy" (1; #90),
#  "ZonePercentage" (1; #91),
#  "ZoneVariance" (1; #92)]

# %%
# Feature importance
model.make_inspector().variable_importances()
# Out:
# {'INV_MEAN_MIN_DEPTH': [("LongRunHighGrayLevelEmphasis" (1; #51),
#    0.1249009754958935),
#   ("LargeDependenceHighGrayLevelEmphasis" (1; #48), 0.11746753468284962),
#   ("GrayLevelNonUniformity.2" (1; #23), 0.11606401899601618),
#   ("90Percentile" (1; #1), 0.11577986452585738),
#   ("HighGrayLevelEmphasis" (1; #29), 0.11303770701377074),
#   ("Autocorrelation" (1; #2), 0.11273683712443168),
#   ("Busyness" (1; #3), 0.11189538153077921),
#   ("HighGrayLevelZoneEmphasis" (1; #31), 0.11098438638418545),
#   ("Coarseness" (1; #7), 0.11092008743714608),
#   ("Energy" (1; #19), 0.11033710928282213),
#   ("RootMeanSquared" (1; #65), 0.10950784507291231),
#   ("Median" (1; #61), 0.10938775577148965),
#   ("TotalEnergy" (1; #87), 0.10844998447983151),
#   ("Maximum" (1; #57), 0.10809893176034772),
#   ("HighGrayLevelRunEmphasis" (1; #30), 0.10803998287043336),
#   ("SumAverage" (1; #84), 0.10777309923934258),
#   ("Idn" (1; #35), 0.10754986103153166),
#   ("Idmn" (1; #34), 0.10667888872961775),
#   ("LargeAreaHighGrayLevelEmphasis" (1; #45), 0.10619255877640767),
#   ("Mean" (1; #59), 0.10618313658483892),
#   ("JointAverage" (1; #40), 0.1047612364918892),
#   ("Skewness" (1; #76), 0.1046562771468194),
#   ("SmallDependenceLowGrayLevelEmphasis" (1; #82), 0.10384922399953339),
#   ("SmallAreaHighGrayLevelEmphasis" (1; #78), 0.10321198482147295),
#   ("ShortRunHighGrayLevelEmphasis" (1; #72), 0.10291352408796794),
#   ("DependenceNonUniformity" (1; #13), 0.10284608165883416),
#   ("DependenceEntropy" (1; #12), 0.10246782966764979),
#   ("Imc1" (1; #36), 0.10239596387681892),
#   ("InverseVariance" (1; #39), 0.10219054765882706),
#   ("Correlation" (1; #11), 0.10218492407706331),
#   ("LowGrayLevelRunEmphasis" (1; #54), 0.10217494214783727),
#   ("ClusterShade" (1; #5), 0.10213663087220012),
#   ("LowGrayLevelEmphasis" (1; #53), 0.10203762012128594),
#   ("ShortRunLowGrayLevelEmphasis" (1; #73), 0.10195129966398958),
#   ("LowGrayLevelZoneEmphasis" (1; #55), 0.1017651006468822),
#   ("SmallDependenceHighGrayLevelEmphasis" (1; #81), 0.10141550443782062),
#   ("LargeDependenceEmphasis" (1; #47), 0.1013730176086486),
#   ("DependenceNonUniformityNormalized" (1; #14), 0.10122997608694556),
#   ("ZonePercentage" (1; #91), 0.10122511165540234),
#   ("Strength" (1; #83), 0.10109543488403905),
#   ("DependenceVariance" (1; #15), 0.10096810152380431),
#   ("LongRunLowGrayLevelEmphasis" (1; #52), 0.10082204349233727),
#   ("SmallDependenceEmphasis" (1; #80), 0.10080444579444903),
#   ("RunVariance" (1; #70), 0.10046332253085616),
#   ("LargeAreaLowGrayLevelEmphasis" (1; #46), 0.10044096355025334),
#   ("LargeDependenceLowGrayLevelEmphasis" (1; #49), 0.10041179742703561),
#   ("MCC" (1; #56), 0.10029844321421028),
#   ("Imc2" (1; #37), 0.10022442799985443),
#   ("10Percentile" (1; #0), 0.10015749488773776),
#   ("RunPercentage" (1; #69), 0.10012998621507246),
#   ("Contrast.1" (1; #10), 0.10001052085570634),
#   ("LongRunEmphasis" (1; #50), 0.09976179260058005),
#   ("MaximumProbability" (1; #58), 0.09975766262372134),
#   ("Minimum" (1; #62), 0.09962437957958238),
#   ("Kurtosis" (1; #43), 0.09955144925544601),
#   ("Idm" (1; #33), 0.09941887067005485),
#   ("Range" (1; #63), 0.09917915988516261),
#   ("GrayLevelNonUniformity.1" (1; #22), 0.09912832944229638),
#   ("GrayLevelNonUniformity" (1; #21), 0.09911957223264085),
#   ("Contrast" (1; #9), 0.0990954516643603),
#   ("DifferenceVariance" (1; #18), 0.09905084428497973),
#   ("DifferenceEntropy" (1; #17), 0.09901581810692656),
#   ("SmallAreaLowGrayLevelEmphasis" (1; #79), 0.09900268562270358),
#   ("Uniformity" (1; #88), 0.09897535483339354),
#   ("Id" (1; #32), 0.09896627080976798),
#   ("SumEntropy" (1; #85), 0.09895952160634018),
#   ("SizeZoneNonUniformity" (1; #74), 0.09894613291677246),
#   ("DifferenceAverage" (1; #16), 0.09891352712809247),
#   ("RunLengthNonUniformity" (1; #67), 0.09882952151154341),
#   ("Entropy" (1; #20), 0.09878085307679949),
#   ("RunEntropy" (1; #66), 0.09867596328101193),
#   ("GrayLevelNonUniformityNormalized.1" (1; #25), 0.09866343509668536),
#   ("ShortRunEmphasis" (1; #71), 0.09865660487386513),
#   ("Complexity" (1; #8), 0.09863890263368197),
#   ("ZoneEntropy" (1; #90), 0.09860756680279674),
#   ("GrayLevelVariance.2" (1; #28), 0.0984892987838914),
#   ("SizeZoneNonUniformityNormalized" (1; #75), 0.09848477367545817),
#   ("JointEnergy" (1; #41), 0.09846430037935093),
#   ("ClusterProminence" (1; #4), 0.09841117691249117),
#   ("GrayLevelNonUniformityNormalized" (1; #24), 0.09836572427509917),
#   ("RunLengthNonUniformityNormalized" (1; #68), 0.09836132020188651),
#   ("SmallAreaEmphasis" (1; #77), 0.09824439430247026),
#   ("InterquartileRange" (1; #38), 0.09823530423206871),
#   ("GrayLevelVariance" (1; #26), 0.09802179973899906),
#   ("RobustMeanAbsoluteDeviation" (1; #64), 0.09796398230916833),
#   ("LargeAreaEmphasis" (1; #44), 0.09795819969969193),
#   ("SumSquares" (1; #86), 0.0979359735678817),
#   ("ZoneVariance" (1; #92), 0.097920274062632),
#   ("JointEntropy" (1; #42), 0.0979042665199325),
#   ("MeanAbsoluteDeviation" (1; #60), 0.09785125311524212),
#   ("GrayLevelVariance.1" (1; #27), 0.09772374640971156),
#   ("ClusterTendency" (1; #6), 0.0975939489785561),
#   ("Variance" (1; #89), 0.09757073577536612)],
#  'NUM_AS_ROOT': [("90Percentile" (1; #1), 31.0),
#   ("HighGrayLevelZoneEmphasis" (1; #31), 29.0),
#   ("LongRunHighGrayLevelEmphasis" (1; #51), 29.0),
#   ("HighGrayLevelEmphasis" (1; #29), 27.0),
#   ("Energy" (1; #19), 22.0),
#   ("Autocorrelation" (1; #2), 19.0),
#   ("RootMeanSquared" (1; #65), 19.0),
#   ("HighGrayLevelRunEmphasis" (1; #30), 18.0),
#   ("TotalEnergy" (1; #87), 18.0),
#   ("SumAverage" (1; #84), 15.0),
#   ("Mean" (1; #59), 10.0),
#   ("Maximum" (1; #57), 7.0),
#   ("ShortRunHighGrayLevelEmphasis" (1; #72), 7.0),
#   ("JointAverage" (1; #40), 6.0),
#   ("ShortRunLowGrayLevelEmphasis" (1; #73), 6.0),
#   ("SmallAreaHighGrayLevelEmphasis" (1; #78), 5.0),
#   ("Busyness" (1; #3), 4.0),
#   ("Median" (1; #61), 4.0),
#   ("LargeDependenceHighGrayLevelEmphasis" (1; #48), 3.0),
#   ("LowGrayLevelRunEmphasis" (1; #54), 3.0),
#   ("LowGrayLevelZoneEmphasis" (1; #55), 3.0),
#   ("LowGrayLevelEmphasis" (1; #53), 2.0),
#   ("SmallDependenceHighGrayLevelEmphasis" (1; #81), 2.0),
#   ("SmallDependenceLowGrayLevelEmphasis" (1; #82), 2.0),
#   ("10Percentile" (1; #0), 1.0),
#   ("DependenceEntropy" (1; #12), 1.0),
#   ("GrayLevelNonUniformity" (1; #21), 1.0),
#   ("JointEntropy" (1; #42), 1.0),
#   ("LargeAreaLowGrayLevelEmphasis" (1; #46), 1.0),
#   ("LongRunLowGrayLevelEmphasis" (1; #52), 1.0),
#   ("MCC" (1; #56), 1.0),
#   ("Minimum" (1; #62), 1.0),
#   ("SumEntropy" (1; #85), 1.0)],
#  'SUM_SCORE': [("LongRunHighGrayLevelEmphasis" (1; #51), 185363.02241627598),
#   ("90Percentile" (1; #1), 154445.203796714),
#   ("HighGrayLevelEmphasis" (1; #29), 133106.10581334605),
#   ("HighGrayLevelZoneEmphasis" (1; #31), 133073.95637301743),
#   ("Autocorrelation" (1; #2), 110955.2882411178),
#   ("Energy" (1; #19), 110744.68749180589),
#   ("RootMeanSquared" (1; #65), 99745.90931422343),
#   ("LargeDependenceHighGrayLevelEmphasis" (1; #48), 95705.32605024091),
#   ("TotalEnergy" (1; #87), 92527.60510414073),
#   ("HighGrayLevelRunEmphasis" (1; #30), 92497.31243750596),
#   ("SumAverage" (1; #84), 78353.1679427746),
#   ("Idn" (1; #35), 70285.67855851217),
#   ("GrayLevelNonUniformity.2" (1; #23), 68091.3497326553),
#   ("Maximum" (1; #57), 65419.25299303102),
#   ("Mean" (1; #59), 61681.89020617057),
#   ("Busyness" (1; #3), 59393.79254965655),
#   ("Idmn" (1; #34), 56103.010488774686),
#   ("Median" (1; #61), 51422.09272323903),
#   ("JointAverage" (1; #40), 46671.2058144715),
#   ("Coarseness" (1; #7), 45535.38035242357),
#   ("ShortRunHighGrayLevelEmphasis" (1; #72), 41319.92819383125),
#   ("SmallAreaHighGrayLevelEmphasis" (1; #78), 40636.55536078543),
#   ("LargeAreaHighGrayLevelEmphasis" (1; #45), 38067.93625946998),
#   ("ShortRunLowGrayLevelEmphasis" (1; #73), 30203.585451336414),
#   ("LowGrayLevelRunEmphasis" (1; #54), 27059.655021906645),
#   ("SmallDependenceLowGrayLevelEmphasis" (1; #82), 26150.740413762494),
#   ("Skewness" (1; #76), 25096.871756201366),
#   ("LowGrayLevelZoneEmphasis" (1; #55), 24788.247574474473),
#   ("SmallDependenceHighGrayLevelEmphasis" (1; #81), 23782.986783801083),
#   ("DependenceEntropy" (1; #12), 23506.934457998937),
#   ("LowGrayLevelEmphasis" (1; #53), 21539.74506643281),
#   ("Imc1" (1; #36), 21066.132583141793),
#   ("DependenceNonUniformity" (1; #13), 20342.176614130258),
#   ("ClusterShade" (1; #5), 19935.017081756905),
#   ("InverseVariance" (1; #39), 19428.490149456244),
#   ("DependenceVariance" (1; #15), 17018.838441505442),
#   ("Correlation" (1; #11), 16805.386941741275),
#   ("LargeDependenceEmphasis" (1; #47), 16790.055449327225),
#   ("ZonePercentage" (1; #91), 16466.3551563398),
#   ("LongRunLowGrayLevelEmphasis" (1; #52), 15874.560330654152),
#   ("Strength" (1; #83), 15514.749506660206),
#   ("DependenceNonUniformityNormalized" (1; #14), 15125.849622170357),
#   ("Imc2" (1; #37), 14904.51995009568),
#   ("LargeAreaLowGrayLevelEmphasis" (1; #46), 14633.783265111835),
#   ("10Percentile" (1; #0), 14504.507525913257),
#   ("LargeDependenceLowGrayLevelEmphasis" (1; #49), 14483.069161411764),
#   ("Contrast.1" (1; #10), 14164.414158823281),
#   ("RunVariance" (1; #70), 14112.633269544407),
#   ("SmallDependenceEmphasis" (1; #80), 13087.067697728287),
#   ("MCC" (1; #56), 12551.011876661942),
#   ("RunPercentage" (1; #69), 12421.02921826936),
#   ("Range" (1; #63), 12346.297626985097),
#   ("LongRunEmphasis" (1; #50), 12292.918814341961),
#   ("MaximumProbability" (1; #58), 11635.715408559881),
#   ("Contrast" (1; #9), 11566.198326072967),
#   ("Idm" (1; #33), 11355.226232529887),
#   ("GrayLevelNonUniformity" (1; #21), 11041.97164156973),
#   ("GrayLevelNonUniformity.1" (1; #22), 10853.068652278664),
#   ("DifferenceVariance" (1; #18), 10722.275790182264),
#   ("Minimum" (1; #62), 10694.86653737374),
#   ("SumEntropy" (1; #85), 10420.21097852391),
#   ("DifferenceAverage" (1; #16), 10239.819761630155),
#   ("Kurtosis" (1; #43), 9930.627153523403),
#   ("Uniformity" (1; #88), 9816.896555695921),
#   ("ZoneEntropy" (1; #90), 9385.23432151854),
#   ("SmallAreaLowGrayLevelEmphasis" (1; #79), 9375.481142533528),
#   ("SizeZoneNonUniformity" (1; #74), 9303.848443234174),
#   ("DifferenceEntropy" (1; #17), 9262.307718378288),
#   ("RunEntropy" (1; #66), 9097.339952205139),
#   ("Id" (1; #32), 9057.703288327579),
#   ("RunLengthNonUniformity" (1; #67), 8938.204189917746),
#   ("GrayLevelNonUniformityNormalized.1" (1; #25), 8872.671255044726),
#   ("JointEnergy" (1; #41), 8685.998572741624),
#   ("Entropy" (1; #20), 8621.2469337258),
#   ("ShortRunEmphasis" (1; #71), 8117.985917227755),
#   ("RunLengthNonUniformityNormalized" (1; #68), 7613.5919103476235),
#   ("SizeZoneNonUniformityNormalized" (1; #75), 7445.437860335786),
#   ("InterquartileRange" (1; #38), 7397.945963148649),
#   ("ClusterProminence" (1; #4), 7368.431545126945),
#   ("GrayLevelVariance.2" (1; #28), 7283.925959756394),
#   ("GrayLevelNonUniformityNormalized" (1; #24), 7190.157638757538),
#   ("SmallAreaEmphasis" (1; #77), 6898.074400949043),
#   ("LargeAreaEmphasis" (1; #44), 6873.553799906335),
#   ("Complexity" (1; #8), 6854.280234018786),
#   ("RobustMeanAbsoluteDeviation" (1; #64), 6757.497347804145),
#   ("ZoneVariance" (1; #92), 6750.913772135069),
#   ("GrayLevelVariance" (1; #26), 6160.30852844524),
#   ("MeanAbsoluteDeviation" (1; #60), 6041.24598776417),
#   ("JointEntropy" (1; #42), 5615.211547598605),
#   ("SumSquares" (1; #86), 5379.551917971591),
#   ("ClusterTendency" (1; #6), 4952.085412790201),
#   ("GrayLevelVariance.1" (1; #27), 4528.194583204684),
#   ("Variance" (1; #89), 4245.816329446721)],
#  'NUM_NODES': [("Idn" (1; #35), 1877.0),
#   ("Idmn" (1; #34), 1626.0),
#   ("Skewness" (1; #76), 1045.0),
#   ("GrayLevelNonUniformity.2" (1; #23), 1011.0),
#   ("Maximum" (1; #57), 994.0),
#   ("Busyness" (1; #3), 913.0),
#   ("ClusterShade" (1; #5), 906.0),
#   ("LargeDependenceHighGrayLevelEmphasis" (1; #48), 901.0),
#   ("Coarseness" (1; #7), 894.0),
#   ("Median" (1; #61), 821.0),
#   ("LongRunHighGrayLevelEmphasis" (1; #51), 805.0),
#   ("90Percentile" (1; #1), 696.0),
#   ("SmallAreaHighGrayLevelEmphasis" (1; #78), 692.0),
#   ("Correlation" (1; #11), 678.0),
#   ("DependenceEntropy" (1; #12), 650.0),
#   ("Imc1" (1; #36), 643.0),
#   ("Contrast.1" (1; #10), 632.0),
#   ("Kurtosis" (1; #43), 618.0),
#   ("Strength" (1; #83), 607.0),
#   ("Autocorrelation" (1; #2), 593.0),
#   ("HighGrayLevelZoneEmphasis" (1; #31), 589.0),
#   ("Range" (1; #63), 587.0),
#   ("LargeAreaHighGrayLevelEmphasis" (1; #45), 566.0),
#   ("MCC" (1; #56), 536.0),
#   ("Imc2" (1; #37), 533.0),
#   ("Contrast" (1; #9), 520.0),
#   ("JointAverage" (1; #40), 518.0),
#   ("SmallDependenceHighGrayLevelEmphasis" (1; #81), 518.0),
#   ("DifferenceVariance" (1; #18), 513.0),
#   ("RootMeanSquared" (1; #65), 504.0),
#   ("SmallDependenceLowGrayLevelEmphasis" (1; #82), 501.0),
#   ("Energy" (1; #19), 495.0),
#   ("TotalEnergy" (1; #87), 494.0),
#   ("HighGrayLevelEmphasis" (1; #29), 485.0),
#   ("DependenceVariance" (1; #15), 481.0),
#   ("SumAverage" (1; #84), 475.0),
#   ("RunVariance" (1; #70), 467.0),
#   ("LowGrayLevelZoneEmphasis" (1; #55), 466.0),
#   ("LargeDependenceLowGrayLevelEmphasis" (1; #49), 461.0),
#   ("DifferenceAverage" (1; #16), 460.0),
#   ("10Percentile" (1; #0), 458.0),
#   ("HighGrayLevelRunEmphasis" (1; #30), 449.0),
#   ("DifferenceEntropy" (1; #17), 447.0),
#   ("LowGrayLevelEmphasis" (1; #53), 442.0),
#   ("Mean" (1; #59), 442.0),
#   ("InterquartileRange" (1; #38), 441.0),
#   ("LowGrayLevelRunEmphasis" (1; #54), 438.0),
#   ("Minimum" (1; #62), 436.0),
#   ("LargeAreaLowGrayLevelEmphasis" (1; #46), 435.0),
#   ("ZoneEntropy" (1; #90), 435.0),
#   ("ShortRunLowGrayLevelEmphasis" (1; #73), 432.0),
#   ("LongRunLowGrayLevelEmphasis" (1; #52), 431.0),
#   ("DependenceNonUniformity" (1; #13), 425.0),
#   ("RunEntropy" (1; #66), 425.0),
#   ("MaximumProbability" (1; #58), 424.0),
#   ("Complexity" (1; #8), 416.0),
#   ("SmallAreaLowGrayLevelEmphasis" (1; #79), 414.0),
#   ("InverseVariance" (1; #39), 407.0),
#   ("GrayLevelNonUniformityNormalized.1" (1; #25), 406.0),
#   ("SumEntropy" (1; #85), 406.0),
#   ("ClusterProminence" (1; #4), 402.0),
#   ("RobustMeanAbsoluteDeviation" (1; #64), 402.0),
#   ("SmallAreaEmphasis" (1; #77), 399.0),
#   ("LongRunEmphasis" (1; #50), 398.0),
#   ("GrayLevelVariance.2" (1; #28), 397.0),
#   ("ShortRunHighGrayLevelEmphasis" (1; #72), 397.0),
#   ("SizeZoneNonUniformity" (1; #74), 389.0),
#   ("GrayLevelNonUniformity.1" (1; #22), 388.0),
#   ("SizeZoneNonUniformityNormalized" (1; #75), 388.0),
#   ("LargeDependenceEmphasis" (1; #47), 386.0),
#   ("Uniformity" (1; #88), 383.0),
#   ("ZonePercentage" (1; #91), 383.0),
#   ("GrayLevelNonUniformityNormalized" (1; #24), 370.0),
#   ("SmallDependenceEmphasis" (1; #80), 366.0),
#   ("GrayLevelNonUniformity" (1; #21), 364.0),
#   ("Id" (1; #32), 358.0),
#   ("DependenceNonUniformityNormalized" (1; #14), 357.0),
#   ("Idm" (1; #33), 355.0),
#   ("Entropy" (1; #20), 343.0),
#   ("ShortRunEmphasis" (1; #71), 341.0),
#   ("MeanAbsoluteDeviation" (1; #60), 340.0),
#   ("RunPercentage" (1; #69), 338.0),
#   ("ZoneVariance" (1; #92), 338.0),
#   ("JointEnergy" (1; #41), 337.0),
#   ("GrayLevelVariance" (1; #26), 324.0),
#   ("RunLengthNonUniformityNormalized" (1; #68), 324.0),
#   ("LargeAreaEmphasis" (1; #44), 319.0),
#   ("SumSquares" (1; #86), 311.0),
#   ("RunLengthNonUniformity" (1; #67), 310.0),
#   ("ClusterTendency" (1; #6), 306.0),
#   ("JointEntropy" (1; #42), 278.0),
#   ("Variance" (1; #89), 268.0),
#   ("GrayLevelVariance.1" (1; #27), 263.0)]}

# %%
# Model self evaluation
model.make_inspector().evaluation()
# Out:
# Evaluation(num_examples=13938, accuracy=0.896633120917147, loss=0.27568601504003754, rmse=None, ndcg=None, aucs=None, auuc=None, qini=None)

# %%
logs = model.make_inspector().training_logs()

plt.figure(figsize=(12, 4))
plt.subplot(1, 2, 1)
plt.plot([log.num_trees for log in logs], [log.evaluation.accuracy for log in logs])
plt.xlabel("Number of trees")
plt.ylabel("Accuracy (out-of-bag)")
plt.subplot(1, 2, 2)
plt.plot([log.num_trees for log in logs], [log.evaluation.loss for log in logs])
plt.xlabel("Number of trees")
plt.ylabel("Logloss (out-of-bag)")
plt.show()

# %% [markdown]
# Calculate the score of our hold-out validation dataset

# %%
predictions = model.predict(val_ds)
y_true      = validation_data["label"]

from sklearn.metrics import roc_auc_score
ROC_AUC = roc_auc_score(y_true, predictions)
print("The ROC AUC score is %.5f" % ROC_AUC )
# Out:
# 1/2 [==============>...............] - ETA: 0s
# 2/2 [==============================] - 0s 22ms/step
# The ROC AUC score is 0.99881

# %%
# Compute binary classification metrics with sklearn
import numpy as np
from sklearn.metrics import (
    accuracy_score,
    precision_score,
    recall_score,
    f1_score,
    roc_auc_score,
    average_precision_score,
    confusion_matrix,
    classification_report,
    matthews_corrcoef,
    log_loss,
    brier_score_loss,
)

# Get predictions (probabilities or class labels)
preds = model.predict(test_ds)
# If model outputs probabilities, convert to labels by threshold 0.5
if preds.ndim == 2:
    # For TFDF classification, preds may be class probabilities with shape (N, 2)
    if preds.shape[1] == 2:
        pos_probs = preds[:, 1]
    else:
        # If single-probability column (positive class)
        pos_probs = preds[:, -1]
    y_pred = (pos_probs >= 0.5).astype(int)
else:
    # Already class labels
    y_pred = preds.astype(int)
    pos_probs = None

# Ground truth labels (must be 0/1 integers)
y_true = test_data["label"].astype(int).to_numpy()

# Core metrics
metrics = {}
metrics["accuracy"] = accuracy_score(y_true, y_pred)
metrics["precision"] = precision_score(y_true, y_pred, zero_division=0)
metrics["recall"] = recall_score(y_true, y_pred, zero_division=0)
metrics["f1"] = f1_score(y_true, y_pred, zero_division=0)
metrics["mcc"] = matthews_corrcoef(y_true, y_pred)

# Probabilistic metrics (only if we have probabilities)
if pos_probs is not None:
    metrics["roc_auc"] = roc_auc_score(y_true, pos_probs)
    metrics["pr_auc"] = average_precision_score(y_true, pos_probs)
    metrics["log_loss"] = log_loss(y_true, pos_probs, labels=[0,1])
    metrics["brier_score"] = brier_score_loss(y_true, pos_probs)

# Confusion matrix and detailed report
cm = confusion_matrix(y_true, y_pred, labels=[0,1])
report = classification_report(y_true, y_pred, digits=4)

print("Sklearn binary metrics:")
for k, v in metrics.items():
    print(f"{k}: {v:.4f}")
print("\nConfusion matrix:\n", cm)
print("\nClassification report:\n", report)
# Out:
# 1/5 [=====>........................] - ETA: 0s
# 4/5 [=======================>......] - ETA: 0s
# 5/5 [==============================] - 0s 19ms/step
# Sklearn binary metrics:
# accuracy: 0.9646
# precision: 0.8560
# recall: 0.7683
# f1: 0.8098
# mcc: 0.7917
# roc_auc: 0.9800
# pr_auc: 0.8997
# log_loss: 0.0945
# brier_score: 0.0256
#
# Confusion matrix:
#  [[3716   53]
#  [  95  315]]
#
# Classification report:
#                precision    recall  f1-score   support
#
#            0     0.9751    0.9859    0.9805      3769
#            1     0.8560    0.7683    0.8098       410
#
#     accuracy                         0.9646      4179
#    macro avg     0.9155    0.8771    0.8951      4179
# weighted avg     0.9634    0.9646    0.9637      4179
