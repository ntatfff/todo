# %%
# Import packages and modules
import numpy  as np
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow_decision_forests as tfdf

from sklearn.model_selection import train_test_split
# Out:
# 2026-09-11 08:11:41.426075: I tensorflow/core/util/port.cc:113] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2026-09-11 08:11:41.476940: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2026-09-11 08:11:46.783921: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
# Check the version of TensorFlow Decision Forests
print("Found TensorFlow Decision Forests v" + tfdf.__version__)
# Out:
# Found TensorFlow Decision Forests v1.9.1

# %%
datasetPath = "dataset/10p/all/kernel3/"

# %%
# Parameters
datasetPath = "dataset/10p/gldm/kernel4/"

# %%
# train/validation/test = 70/10/20
train_data = pd.read_csv(f"{datasetPath}dataset.train.csv")
validation_data = pd.read_csv(f"{datasetPath}dataset.validation.csv")
test_data = pd.read_csv(f"{datasetPath}dataset.test.csv")

# %%
from sklearn.utils.class_weight import compute_class_weight

# tinh class weight tren tap train
classes = np.array([0, 1])
weights = compute_class_weight(class_weight="balanced", classes=classes, y=train_data["label"])
class_weight = {0: weights[0], 1: weights[1]}

# gan sample_weight cho tung dong
train_data["sample_weight"] = train_data["label"].map(class_weight)
validation_data["sample_weight"] = validation_data["label"].map(class_weight)
test_data["sample_weight"] = test_data["label"].map(class_weight)

# Convert the dataset into a TensorFlow dataset.
train_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    train_data, label="label", weight="sample_weight"
)         
val_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    validation_data, label="label", weight="sample_weight"
)
test_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    test_data, label="label", weight="sample_weight"
)
# Out:
# 2026-09-11 08:12:02.618835: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:984] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2026-09-11 08:12:02.620654: W tensorflow/core/common_runtime/gpu/gpu_device.cc:2251] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...

# %%
import keras

# %%
# %%time

# Train a Gradient Boosted Trees model.
model = tfdf.keras.GradientBoostedTreesModel()

# Add evaluation metrics
model.compile(
    metrics=["accuracy"]
)
model.fit(x=train_ds)

# # Train a Gradient Boosted Trees model.
# model = tfdf.keras.GradientBoostedTreesModel(num_trees=1500)
# model.fit(train_ds)
# Out:
# Use /tmp/tmpwkmeukfs as temporary training directory
# Reading training dataset...
# [WARNING 26-09-11 08:12:02.7484 UTC gradient_boosted_trees.cc:1840] "goss_alpha" set but "sampling_method" not equal to "GOSS".
# [WARNING 26-09-11 08:12:02.7484 UTC gradient_boosted_trees.cc:1851] "goss_beta" set but "sampling_method" not equal to "GOSS".
# [WARNING 26-09-11 08:12:02.7484 UTC gradient_boosted_trees.cc:1865] "selective_gradient_boosting_ratio" set but "sampling_method" not equal to "SELGB".
# Training dataset read in 0:00:03.229065. Found 13938 examples.
# Training model...
# Model trained in 0:00:01.045643
# Compiling model...
# [INFO 26-09-11 08:12:07.0451 UTC kernel.cc:1233] Loading model from path /tmp/tmpwkmeukfs/model/ with prefix ce45892c0ccc4e32
# [INFO 26-09-11 08:12:07.0480 UTC quick_scorer_extended.cc:911] The binary was compiled without AVX2 support, but your CPU supports it. Enable it for faster model inference.
# [INFO 26-09-11 08:12:07.0482 UTC abstract_model.cc:1362] Engine "GradientBoostedTreesQuickScorerExtended" built
# [INFO 26-09-11 08:12:07.0483 UTC kernel.cc:1061] Use fast generic engine
# Model compiled.
# CPU times: user 11.8 s, sys: 535 ms, total: 12.4 s
# Wall time: 8.24 s

# %%
# Evaluate the model
evaluate = model.evaluate(val_ds, return_dict=True)
print()

for name, value in evaluate.items():
    print(f"{name}: {value:.4f}")
# Out:
# WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 1/2 [==============>...............] - ETA: 3s - loss: 0.0000e+00 - accuracy: 0.9850
# 2/2 [==============================] - 4s 10ms/step - loss: 0.0000e+00 - accuracy: 0.9744
# loss: 0.0000
# accuracy: 0.9744

# %%
# Model Summary
model.summary()
# Out:
# Model: "gradient_boosted_trees_model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
# =================================================================
# Total params: 1 (1.00 Byte)
# Trainable params: 0 (0.00 Byte)
# Non-trainable params: 1 (1.00 Byte)
# _________________________________________________________________
# Type: "GRADIENT_BOOSTED_TREES"
# Task: CLASSIFICATION
# Label: "__LABEL"
#
# Input Features (14):
# 	DependenceEntropy
# 	DependenceNonUniformity
# 	DependenceNonUniformityNormalized
# 	DependenceVariance
# 	GrayLevelNonUniformity
# 	GrayLevelVariance
# 	HighGrayLevelEmphasis
# 	LargeDependenceEmphasis
# 	LargeDependenceHighGrayLevelEmphasis
# 	LargeDependenceLowGrayLevelEmphasis
# 	LowGrayLevelEmphasis
# 	SmallDependenceEmphasis
# 	SmallDependenceHighGrayLevelEmphasis
# 	SmallDependenceLowGrayLevelEmphasis
#
# Trained with weights
#
# Variable Importance: INV_MEAN_MIN_DEPTH:
#     1.                "HighGrayLevelEmphasis"  0.357496 ################
#     2. "LargeDependenceHighGrayLevelEmphasis"  0.340164 ##############
#     3.                    "DependenceEntropy"  0.227247 ####
#     4. "SmallDependenceHighGrayLevelEmphasis"  0.202831 ##
#     5.  "LargeDependenceLowGrayLevelEmphasis"  0.196938 ##
#     6.  "SmallDependenceLowGrayLevelEmphasis"  0.185451 #
#     7.               "GrayLevelNonUniformity"  0.185266 #
#     8.                   "DependenceVariance"  0.182559
#     9.                 "LowGrayLevelEmphasis"  0.179126
#    10.                    "GrayLevelVariance"  0.178721
#    11.              "SmallDependenceEmphasis"  0.177196
#    12.              "DependenceNonUniformity"  0.175004
#    13.              "LargeDependenceEmphasis"  0.173639
#    14.    "DependenceNonUniformityNormalized"  0.173412
#
# Variable Importance: NUM_AS_ROOT:
#     1.                "HighGrayLevelEmphasis" 30.000000 ################
#     2. "LargeDependenceHighGrayLevelEmphasis" 14.000000 #######
#     3.  "LargeDependenceLowGrayLevelEmphasis"  5.000000 ##
#     4. "SmallDependenceHighGrayLevelEmphasis"  5.000000 ##
#     5.                    "DependenceEntropy"  1.000000
#
# Variable Importance: NUM_NODES:
#     1.                "HighGrayLevelEmphasis" 231.000000 ################
#     2. "LargeDependenceHighGrayLevelEmphasis" 231.000000 ################
#     3.                    "DependenceEntropy" 196.000000 #############
#     4. "SmallDependenceHighGrayLevelEmphasis" 155.000000 ##########
#     5.  "LargeDependenceLowGrayLevelEmphasis" 110.000000 ######
#     6.               "GrayLevelNonUniformity" 100.000000 ######
#     7.  "SmallDependenceLowGrayLevelEmphasis" 92.000000 #####
#     8.                 "LowGrayLevelEmphasis" 80.000000 ####
#     9.                   "DependenceVariance" 78.000000 ####
#    10.                    "GrayLevelVariance" 68.000000 ###
#    11.              "SmallDependenceEmphasis" 68.000000 ###
#    12.              "LargeDependenceEmphasis" 39.000000 #
#    13.    "DependenceNonUniformityNormalized" 26.000000
#    14.              "DependenceNonUniformity" 21.000000
#
# Variable Importance: SUM_SCORE:
#     1.                "HighGrayLevelEmphasis" 9246.790789 ################
#     2. "LargeDependenceHighGrayLevelEmphasis" 2723.195520 ####
#     3.                    "DependenceEntropy" 897.028847 #
#     4. "SmallDependenceHighGrayLevelEmphasis" 424.048919
#     5.  "LargeDependenceLowGrayLevelEmphasis" 393.521589
#     6.               "GrayLevelNonUniformity" 283.942639
#     7.  "SmallDependenceLowGrayLevelEmphasis" 261.824378
#     8.                   "DependenceVariance" 233.625792
#     9.              "SmallDependenceEmphasis" 216.466153
#    10.                 "LowGrayLevelEmphasis" 188.599087
#    11.                    "GrayLevelVariance" 129.872305
#    12.              "LargeDependenceEmphasis" 75.514099
#    13.    "DependenceNonUniformityNormalized" 58.545059
#    14.              "DependenceNonUniformity" 49.602633
#
#
#
# Loss: BINOMIAL_LOG_LIKELIHOOD
# Validation loss value: 0.406355
# Number of trees per iteration: 1
# Node format: NOT_SET
# Number of trees: 55
# Total number of nodes: 3045
#
# Number of nodes by tree:
# Count: 55 Average: 55.3636 StdDev: 5.47511
# Min: 43 Max: 63 Ignored: 0
# ----------------------------------------------
# [ 43, 44)  1   1.82%   1.82% #
# [ 44, 45)  0   0.00%   1.82%
# [ 45, 46)  2   3.64%   5.45% ##
# [ 46, 47)  0   0.00%   5.45%
# [ 47, 48)  5   9.09%  14.55% #####
# [ 48, 49)  0   0.00%  14.55%
# [ 49, 50)  4   7.27%  21.82% ####
# [ 50, 51)  0   0.00%  21.82%
# [ 51, 52)  4   7.27%  29.09% ####
# [ 52, 53)  0   0.00%  29.09%
# [ 53, 54)  3   5.45%  34.55% ###
# [ 54, 55)  0   0.00%  34.55%
# [ 55, 56)  6  10.91%  45.45% #####
# [ 56, 57)  0   0.00%  45.45%
# [ 57, 58) 10  18.18%  63.64% #########
# [ 58, 59)  0   0.00%  63.64%
# [ 59, 60)  5   9.09%  72.73% #####
# [ 60, 61)  0   0.00%  72.73%
# [ 61, 62) 11  20.00%  92.73% ##########
# [ 62, 63]  4   7.27% 100.00% ####
#
# Depth by leafs:
# Count: 1550 Average: 4.89935 StdDev: 0.388794
# Min: 2 Max: 5 Ignored: 0
# ----------------------------------------------
# [ 2, 3)    7   0.45%   0.45%
# [ 3, 4)   26   1.68%   2.13%
# [ 4, 5)   83   5.35%   7.48% #
# [ 5, 5] 1434  92.52% 100.00% ##########
#
# Number of training obs by leaf:
# Count: 1550 Average: 445.003 StdDev: 1179.77
# Min: 5 Max: 9323 Ignored: 0
# ----------------------------------------------
# [    5,  470) 1296  83.61%  83.61% ##########
# [  470,  936)   90   5.81%  89.42% #
# [  936, 1402)   30   1.94%  91.35%
# [ 1402, 1868)   34   2.19%  93.55%
# [ 1868, 2334)   21   1.35%  94.90%
# [ 2334, 2800)   11   0.71%  95.61%
# [ 2800, 3266)    6   0.39%  96.00%
# [ 3266, 3732)    4   0.26%  96.26%
# [ 3732, 4198)    8   0.52%  96.77%
# [ 4198, 4664)    8   0.52%  97.29%
# [ 4664, 5130)   11   0.71%  98.00%
# [ 5130, 5596)    5   0.32%  98.32%
# [ 5596, 6062)    4   0.26%  98.58%
# [ 6062, 6528)    5   0.32%  98.90%
# [ 6528, 6994)    6   0.39%  99.29%
# [ 6994, 7460)    5   0.32%  99.61%
# [ 7460, 7926)    1   0.06%  99.68%
# [ 7926, 8392)    3   0.19%  99.87%
# [ 8392, 8858)    1   0.06%  99.94%
# [ 8858, 9323]    1   0.06% 100.00%
#
# Attribute in nodes:
# 	231 : LargeDependenceHighGrayLevelEmphasis [NUMERICAL]
# 	231 : HighGrayLevelEmphasis [NUMERICAL]
# 	196 : DependenceEntropy [NUMERICAL]
# 	155 : SmallDependenceHighGrayLevelEmphasis [NUMERICAL]
# 	110 : LargeDependenceLowGrayLevelEmphasis [NUMERICAL]
# 	100 : GrayLevelNonUniformity [NUMERICAL]
# 	92 : SmallDependenceLowGrayLevelEmphasis [NUMERICAL]
# 	80 : LowGrayLevelEmphasis [NUMERICAL]
# 	78 : DependenceVariance [NUMERICAL]
# 	68 : SmallDependenceEmphasis [NUMERICAL]
# 	68 : GrayLevelVariance [NUMERICAL]
# 	39 : LargeDependenceEmphasis [NUMERICAL]
# 	26 : DependenceNonUniformityNormalized [NUMERICAL]
# 	21 : DependenceNonUniformity [NUMERICAL]
#
# Attribute in nodes with depth <= 0:
# 	30 : HighGrayLevelEmphasis [NUMERICAL]
# 	14 : LargeDependenceHighGrayLevelEmphasis [NUMERICAL]
# 	5 : SmallDependenceHighGrayLevelEmphasis [NUMERICAL]
# 	5 : LargeDependenceLowGrayLevelEmphasis [NUMERICAL]
# 	1 : DependenceEntropy [NUMERICAL]
#
# Attribute in nodes with depth <= 1:
# 	58 : HighGrayLevelEmphasis [NUMERICAL]
# 	57 : LargeDependenceHighGrayLevelEmphasis [NUMERICAL]
# 	11 : SmallDependenceHighGrayLevelEmphasis [NUMERICAL]
# 	10 : DependenceEntropy [NUMERICAL]
# 	8 : LargeDependenceLowGrayLevelEmphasis [NUMERICAL]
# 	6 : GrayLevelNonUniformity [NUMERICAL]
# 	5 : DependenceVariance [NUMERICAL]
# 	4 : SmallDependenceLowGrayLevelEmphasis [NUMERICAL]
# 	4 : DependenceNonUniformity [NUMERICAL]
# 	2 : DependenceNonUniformityNormalized [NUMERICAL]
#
# Attribute in nodes with depth <= 2:
# 	85 : HighGrayLevelEmphasis [NUMERICAL]
# 	82 : LargeDependenceHighGrayLevelEmphasis [NUMERICAL]
# 	75 : DependenceEntropy [NUMERICAL]
# 	29 : SmallDependenceHighGrayLevelEmphasis [NUMERICAL]
# 	17 : SmallDependenceLowGrayLevelEmphasis [NUMERICAL]
# 	17 : DependenceVariance [NUMERICAL]
# 	15 : LargeDependenceLowGrayLevelEmphasis [NUMERICAL]
# 	15 : GrayLevelVariance [NUMERICAL]
# 	15 : GrayLevelNonUniformity [NUMERICAL]
# 	11 : LowGrayLevelEmphasis [NUMERICAL]
# 	7 : SmallDependenceEmphasis [NUMERICAL]
# 	4 : DependenceNonUniformity [NUMERICAL]
# 	3 : LargeDependenceEmphasis [NUMERICAL]
# 	3 : DependenceNonUniformityNormalized [NUMERICAL]
#
# Attribute in nodes with depth <= 3:
# 	141 : LargeDependenceHighGrayLevelEmphasis [NUMERICAL]
# 	135 : HighGrayLevelEmphasis [NUMERICAL]
# 	110 : DependenceEntropy [NUMERICAL]
# 	81 : SmallDependenceHighGrayLevelEmphasis [NUMERICAL]
# 	55 : LargeDependenceLowGrayLevelEmphasis [NUMERICAL]
# 	48 : SmallDependenceLowGrayLevelEmphasis [NUMERICAL]
# 	38 : GrayLevelNonUniformity [NUMERICAL]
# 	37 : LowGrayLevelEmphasis [NUMERICAL]
# 	37 : DependenceVariance [NUMERICAL]
# 	33 : SmallDependenceEmphasis [NUMERICAL]
# 	32 : GrayLevelVariance [NUMERICAL]
# 	18 : LargeDependenceEmphasis [NUMERICAL]
# 	8 : DependenceNonUniformity [NUMERICAL]
# 	5 : DependenceNonUniformityNormalized [NUMERICAL]
#
# Attribute in nodes with depth <= 5:
# 	231 : LargeDependenceHighGrayLevelEmphasis [NUMERICAL]
# 	231 : HighGrayLevelEmphasis [NUMERICAL]
# 	196 : DependenceEntropy [NUMERICAL]
# 	155 : SmallDependenceHighGrayLevelEmphasis [NUMERICAL]
# 	110 : LargeDependenceLowGrayLevelEmphasis [NUMERICAL]
# 	100 : GrayLevelNonUniformity [NUMERICAL]
# 	92 : SmallDependenceLowGrayLevelEmphasis [NUMERICAL]
# 	80 : LowGrayLevelEmphasis [NUMERICAL]
# 	78 : DependenceVariance [NUMERICAL]
# 	68 : SmallDependenceEmphasis [NUMERICAL]
# 	68 : GrayLevelVariance [NUMERICAL]
# 	39 : LargeDependenceEmphasis [NUMERICAL]
# 	26 : DependenceNonUniformityNormalized [NUMERICAL]
# 	21 : DependenceNonUniformity [NUMERICAL]
#
# Condition type in nodes:
# 	1495 : HigherCondition
# Condition type in nodes with depth <= 0:
# 	55 : HigherCondition
# Condition type in nodes with depth <= 1:
# 	165 : HigherCondition
# Condition type in nodes with depth <= 2:
# 	378 : HigherCondition
# Condition type in nodes with depth <= 3:
# 	778 : HigherCondition
# Condition type in nodes with depth <= 5:
# 	1495 : HigherCondition
#
# Training logs:
# Number of iteration to final model: 55
# 	Iter:1 train-loss:1.249351 valid-loss:1.256980  train-accuracy:0.914918 valid-accuracy:0.896232
# 	Iter:2 train-loss:1.136341 valid-loss:1.152373  train-accuracy:0.915498 valid-accuracy:0.891723
# 	Iter:3 train-loss:1.040521 valid-loss:1.065613  train-accuracy:0.914748 valid-accuracy:0.884859
# 	Iter:4 train-loss:0.955136 valid-loss:0.982460  train-accuracy:0.920690 valid-accuracy:0.898251
# 	Iter:5 train-loss:0.881753 valid-loss:0.915170  train-accuracy:0.919141 valid-accuracy:0.888964
# 	Iter:6 train-loss:0.818033 valid-loss:0.854963  train-accuracy:0.920414 valid-accuracy:0.888964
# 	Iter:16 train-loss:0.472458 valid-loss:0.550942  train-accuracy:0.937681 valid-accuracy:0.891319
# 	Iter:26 train-loss:0.341100 valid-loss:0.451222  train-accuracy:0.951050 valid-accuracy:0.910498
# 	Iter:36 train-loss:0.278549 valid-loss:0.421097  train-accuracy:0.958668 valid-accuracy:0.917026
# 	Iter:46 train-loss:0.235016 valid-loss:0.412453  train-accuracy:0.968819 valid-accuracy:0.920660
# 	Iter:56 train-loss:0.203826 valid-loss:0.409721  train-accuracy:0.973976 valid-accuracy:0.911642
# 	Iter:66 train-loss:0.185064 valid-loss:0.414427  train-accuracy:0.976876 valid-accuracy:0.912854
# 	Iter:76 train-loss:0.169208 valid-loss:0.425282  train-accuracy:0.981453 valid-accuracy:0.901817

# %%
# Model features
model.make_inspector().features()
# Out:
# ["DependenceEntropy" (1; #0),
#  "DependenceNonUniformity" (1; #1),
#  "DependenceNonUniformityNormalized" (1; #2),
#  "DependenceVariance" (1; #3),
#  "GrayLevelNonUniformity" (1; #4),
#  "GrayLevelVariance" (1; #5),
#  "HighGrayLevelEmphasis" (1; #6),
#  "LargeDependenceEmphasis" (1; #7),
#  "LargeDependenceHighGrayLevelEmphasis" (1; #8),
#  "LargeDependenceLowGrayLevelEmphasis" (1; #9),
#  "LowGrayLevelEmphasis" (1; #10),
#  "SmallDependenceEmphasis" (1; #11),
#  "SmallDependenceHighGrayLevelEmphasis" (1; #12),
#  "SmallDependenceLowGrayLevelEmphasis" (1; #13)]

# %%
# Feature importance
model.make_inspector().variable_importances()
# Out:
# {'INV_MEAN_MIN_DEPTH': [("HighGrayLevelEmphasis" (1; #6), 0.3574956831298491),
#   ("LargeDependenceHighGrayLevelEmphasis" (1; #8), 0.34016384221717744),
#   ("DependenceEntropy" (1; #0), 0.22724738618855078),
#   ("SmallDependenceHighGrayLevelEmphasis" (1; #12), 0.2028314699036852),
#   ("LargeDependenceLowGrayLevelEmphasis" (1; #9), 0.1969380139487488),
#   ("SmallDependenceLowGrayLevelEmphasis" (1; #13), 0.18545124361064105),
#   ("GrayLevelNonUniformity" (1; #4), 0.18526598905107025),
#   ("DependenceVariance" (1; #3), 0.182558816086459),
#   ("LowGrayLevelEmphasis" (1; #10), 0.17912587432599156),
#   ("GrayLevelVariance" (1; #5), 0.17872139322302763),
#   ("SmallDependenceEmphasis" (1; #11), 0.17719604335508743),
#   ("DependenceNonUniformity" (1; #1), 0.1750039293895103),
#   ("LargeDependenceEmphasis" (1; #7), 0.1736387792161707),
#   ("DependenceNonUniformityNormalized" (1; #2), 0.17341219364617205)],
#  'NUM_AS_ROOT': [("HighGrayLevelEmphasis" (1; #6), 30.0),
#   ("LargeDependenceHighGrayLevelEmphasis" (1; #8), 14.0),
#   ("LargeDependenceLowGrayLevelEmphasis" (1; #9), 5.0),
#   ("SmallDependenceHighGrayLevelEmphasis" (1; #12), 5.0),
#   ("DependenceEntropy" (1; #0), 1.0)],
#  'SUM_SCORE': [("HighGrayLevelEmphasis" (1; #6), 9246.790788650997),
#   ("LargeDependenceHighGrayLevelEmphasis" (1; #8), 2723.1955196665826),
#   ("DependenceEntropy" (1; #0), 897.0288465015975),
#   ("SmallDependenceHighGrayLevelEmphasis" (1; #12), 424.048918704115),
#   ("LargeDependenceLowGrayLevelEmphasis" (1; #9), 393.5215889776059),
#   ("GrayLevelNonUniformity" (1; #4), 283.9426389009033),
#   ("SmallDependenceLowGrayLevelEmphasis" (1; #13), 261.8243782910909),
#   ("DependenceVariance" (1; #3), 233.62579202940506),
#   ("SmallDependenceEmphasis" (1; #11), 216.46615288076575),
#   ("LowGrayLevelEmphasis" (1; #10), 188.5990868173292),
#   ("GrayLevelVariance" (1; #5), 129.87230520376116),
#   ("LargeDependenceEmphasis" (1; #7), 75.5140986889021),
#   ("DependenceNonUniformityNormalized" (1; #2), 58.54505852322057),
#   ("DependenceNonUniformity" (1; #1), 49.60263269643745)],
#  'NUM_NODES': [("HighGrayLevelEmphasis" (1; #6), 231.0),
#   ("LargeDependenceHighGrayLevelEmphasis" (1; #8), 231.0),
#   ("DependenceEntropy" (1; #0), 196.0),
#   ("SmallDependenceHighGrayLevelEmphasis" (1; #12), 155.0),
#   ("LargeDependenceLowGrayLevelEmphasis" (1; #9), 110.0),
#   ("GrayLevelNonUniformity" (1; #4), 100.0),
#   ("SmallDependenceLowGrayLevelEmphasis" (1; #13), 92.0),
#   ("LowGrayLevelEmphasis" (1; #10), 80.0),
#   ("DependenceVariance" (1; #3), 78.0),
#   ("GrayLevelVariance" (1; #5), 68.0),
#   ("SmallDependenceEmphasis" (1; #11), 68.0),
#   ("LargeDependenceEmphasis" (1; #7), 39.0),
#   ("DependenceNonUniformityNormalized" (1; #2), 26.0),
#   ("DependenceNonUniformity" (1; #1), 21.0)]}

# %%
# Model self evaluation
model.make_inspector().evaluation()
# Out:
# Evaluation(num_examples=None, accuracy=0.9173622727394104, loss=0.40635526180267334, rmse=None, ndcg=None, aucs=None, auuc=None, qini=None)

# %%
logs = model.make_inspector().training_logs()

plt.figure(figsize=(12, 4))
plt.subplot(1, 2, 1)
plt.plot([log.num_trees for log in logs], [log.evaluation.accuracy for log in logs])
plt.xlabel("Number of trees")
plt.ylabel("Accuracy (out-of-bag)")
plt.subplot(1, 2, 2)
plt.plot([log.num_trees for log in logs], [log.evaluation.loss for log in logs])
plt.xlabel("Number of trees")
plt.ylabel("Logloss (out-of-bag)")
plt.show()

# %% [markdown]
# Calculate the score of our hold-out validation dataset

# %%
predictions = model.predict(val_ds)
y_true      = validation_data["label"]

from sklearn.metrics import roc_auc_score
ROC_AUC = roc_auc_score(y_true, predictions)
print("The ROC AUC score is %.5f" % ROC_AUC )
# Out:
# 1/2 [==============>...............] - ETA: 0s
# 2/2 [==============================] - 0s 4ms/step
# The ROC AUC score is 0.99743

# %%
# Compute binary classification metrics with sklearn
import numpy as np
from sklearn.metrics import (
    accuracy_score,
    precision_score,
    recall_score,
    f1_score,
    roc_auc_score,
    average_precision_score,
    confusion_matrix,
    classification_report,
    matthews_corrcoef,
    log_loss,
    brier_score_loss,
)

# Get predictions (probabilities or class labels)
preds = model.predict(test_ds)
# If model outputs probabilities, convert to labels by threshold 0.5
if preds.ndim == 2:
    # For TFDF classification, preds may be class probabilities with shape (N, 2)
    if preds.shape[1] == 2:
        pos_probs = preds[:, 1]
    else:
        # If single-probability column (positive class)
        pos_probs = preds[:, -1]
    y_pred = (pos_probs >= 0.5).astype(int)
else:
    # Already class labels
    y_pred = preds.astype(int)
    pos_probs = None

# Ground truth labels (must be 0/1 integers)
y_true = test_data["label"].astype(int).to_numpy()

# Core metrics
metrics = {}
metrics["accuracy"] = accuracy_score(y_true, y_pred)
metrics["precision"] = precision_score(y_true, y_pred, zero_division=0)
metrics["recall"] = recall_score(y_true, y_pred, zero_division=0)
metrics["f1"] = f1_score(y_true, y_pred, zero_division=0)
metrics["mcc"] = matthews_corrcoef(y_true, y_pred)

# Probabilistic metrics (only if we have probabilities)
if pos_probs is not None:
    metrics["roc_auc"] = roc_auc_score(y_true, pos_probs)
    metrics["pr_auc"] = average_precision_score(y_true, pos_probs)
    metrics["log_loss"] = log_loss(y_true, pos_probs, labels=[0,1])
    metrics["brier_score"] = brier_score_loss(y_true, pos_probs)

# Confusion matrix and detailed report
cm = confusion_matrix(y_true, y_pred, labels=[0,1])
report = classification_report(y_true, y_pred, digits=4)

print("Sklearn binary metrics:")
for k, v in metrics.items():
    print(f"{k}: {v:.4f}")
print("\nConfusion matrix:\n", cm)
print("\nClassification report:\n", report)
# Out:
# 1/5 [=====>........................] - ETA: 0s
# 5/5 [==============================] - 0s 4ms/step
# Sklearn binary metrics:
# accuracy: 0.9617
# precision: 0.7815
# recall: 0.8463
# f1: 0.8126
# mcc: 0.7921
# roc_auc: 0.9609
# pr_auc: 0.8751
# log_loss: 0.1264
# brier_score: 0.0315
#
# Confusion matrix:
#  [[3672   97]
#  [  63  347]]
#
# Classification report:
#                precision    recall  f1-score   support
#
#            0     0.9831    0.9743    0.9787      3769
#            1     0.7815    0.8463    0.8126       410
#
#     accuracy                         0.9617      4179
#    macro avg     0.8823    0.9103    0.8957      4179
# weighted avg     0.9634    0.9617    0.9624      4179
