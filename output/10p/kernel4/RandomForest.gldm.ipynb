# %%
# Import packages and modules
import numpy  as np
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow_decision_forests as tfdf

from sklearn.model_selection import train_test_split
# Out:
# 2026-09-11 08:20:23.466667: I tensorflow/core/util/port.cc:113] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2026-09-11 08:20:23.505853: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2026-09-11 08:20:27.872839: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
# Check the version of TensorFlow Decision Forests
print("Found TensorFlow Decision Forests v" + tfdf.__version__)
# Out:
# Found TensorFlow Decision Forests v1.9.1

# %%
datasetPath = "dataset/10p/all/kernel3/"

# %%
# Parameters
datasetPath = "dataset/10p/gldm/kernel4/"

# %%
# train/validation/test = 70/10/20
train_data = pd.read_csv(f"{datasetPath}dataset.train.csv")
validation_data = pd.read_csv(f"{datasetPath}dataset.validation.csv")
test_data = pd.read_csv(f"{datasetPath}dataset.test.csv")

# %%
from sklearn.utils.class_weight import compute_class_weight

# tinh class weight tren tap train
classes = np.array([0, 1])
weights = compute_class_weight(class_weight="balanced", classes=classes, y=train_data["label"])
class_weight = {0: weights[0], 1: weights[1]}

# gan sample_weight cho tung dong
train_data["sample_weight"] = train_data["label"].map(class_weight)
validation_data["sample_weight"] = validation_data["label"].map(class_weight)
test_data["sample_weight"] = test_data["label"].map(class_weight)

# Convert the dataset into a TensorFlow dataset.
train_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    train_data, label="label", weight="sample_weight"
)         
val_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    validation_data, label="label", weight="sample_weight"
)
test_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    test_data, label="label", weight="sample_weight"
)
# Out:
# 2026-09-11 08:20:40.843033: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:984] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2026-09-11 08:20:40.844558: W tensorflow/core/common_runtime/gpu/gpu_device.cc:2251] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...

# %%
import keras

# %%
# %%time

# Train a Random Forest model.
model = tfdf.keras.RandomForestModel()

# Add evaluation metrics
model.compile(
    metrics=["accuracy"]
)
model.fit(x=train_ds)

# # Train a Gradient Boosted Trees model.
# model = tfdf.keras.GradientBoostedTreesModel(num_trees=1500)
# model.fit(train_ds)
# Out:
# Use /tmp/tmp3cmy2uha as temporary training directory
# Reading training dataset...
# Training dataset read in 0:00:02.511962. Found 13938 examples.
# Training model...
# Model trained in 0:00:00.924380
# Compiling model...
# [INFO 26-09-11 08:20:44.2395 UTC kernel.cc:1233] Loading model from path /tmp/tmp3cmy2uha/model/ with prefix 2da5a22cb88746f7
# [INFO 26-09-11 08:20:44.3916 UTC decision_forest.cc:734] Model loaded with 300 root(s), 121462 node(s), and 14 input feature(s).
# [INFO 26-09-11 08:20:44.3916 UTC abstract_model.cc:1362] Engine "RandomForestOptPred" built
# [INFO 26-09-11 08:20:44.3916 UTC kernel.cc:1061] Use fast generic engine
# Model compiled.
# CPU times: user 13.2 s, sys: 220 ms, total: 13.4 s
# Wall time: 6.45 s

# %%
# Evaluate the model
evaluate = model.evaluate(val_ds, return_dict=True)
print()

for name, value in evaluate.items():
    print(f"{name}: {value:.4f}")
# Out:
# WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 1/2 [==============>...............] - ETA: 2s - loss: 0.0000e+00 - accuracy: 0.9970
# 2/2 [==============================] - 3s 19ms/step - loss: 0.0000e+00 - accuracy: 0.9897
# loss: 0.0000
# accuracy: 0.9897

# %%
# Model Summary
model.summary()
# Out:
# Model: "random_forest_model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
# =================================================================
# Total params: 1 (1.00 Byte)
# Trainable params: 0 (0.00 Byte)
# Non-trainable params: 1 (1.00 Byte)
# _________________________________________________________________
# Type: "RANDOM_FOREST"
# Task: CLASSIFICATION
# Label: "__LABEL"
#
# Input Features (14):
# 	DependenceEntropy
# 	DependenceNonUniformity
# 	DependenceNonUniformityNormalized
# 	DependenceVariance
# 	GrayLevelNonUniformity
# 	GrayLevelVariance
# 	HighGrayLevelEmphasis
# 	LargeDependenceEmphasis
# 	LargeDependenceHighGrayLevelEmphasis
# 	LargeDependenceLowGrayLevelEmphasis
# 	LowGrayLevelEmphasis
# 	SmallDependenceEmphasis
# 	SmallDependenceHighGrayLevelEmphasis
# 	SmallDependenceLowGrayLevelEmphasis
#
# Trained with weights
#
# Variable Importance: INV_MEAN_MIN_DEPTH:
#     1.                "HighGrayLevelEmphasis"  0.280650 ################
#     2. "LargeDependenceHighGrayLevelEmphasis"  0.220355 ##########
#     3.                 "LowGrayLevelEmphasis"  0.159813 ####
#     4. "SmallDependenceHighGrayLevelEmphasis"  0.155170 ####
#     5.                    "DependenceEntropy"  0.153854 ####
#     6.  "SmallDependenceLowGrayLevelEmphasis"  0.131904 ##
#     7.  "LargeDependenceLowGrayLevelEmphasis"  0.120620 #
#     8.               "GrayLevelNonUniformity"  0.119190 #
#     9.                   "DependenceVariance"  0.110770
#    10.                    "GrayLevelVariance"  0.110560
#    11.              "DependenceNonUniformity"  0.107375
#    12.              "SmallDependenceEmphasis"  0.106833
#    13.    "DependenceNonUniformityNormalized"  0.106552
#    14.              "LargeDependenceEmphasis"  0.105959
#
# Variable Importance: NUM_AS_ROOT:
#     1.                "HighGrayLevelEmphasis" 117.000000 ################
#     2.                 "LowGrayLevelEmphasis" 60.000000 ########
#     3. "SmallDependenceHighGrayLevelEmphasis" 54.000000 #######
#     4. "LargeDependenceHighGrayLevelEmphasis" 33.000000 ####
#     5.  "LargeDependenceLowGrayLevelEmphasis" 16.000000 ##
#     6.  "SmallDependenceLowGrayLevelEmphasis" 11.000000 #
#     7.                    "DependenceEntropy"  4.000000
#     8.               "GrayLevelNonUniformity"  3.000000
#     9.              "DependenceNonUniformity"  1.000000
#    10.              "LargeDependenceEmphasis"  1.000000
#
# Variable Importance: NUM_NODES:
#     1.                    "DependenceEntropy" 5956.000000 ################
#     2. "LargeDependenceHighGrayLevelEmphasis" 5707.000000 ##############
#     3.                "HighGrayLevelEmphasis" 5545.000000 #############
#     4. "SmallDependenceHighGrayLevelEmphasis" 5117.000000 ###########
#     5.               "GrayLevelNonUniformity" 4675.000000 #########
#     6.  "SmallDependenceLowGrayLevelEmphasis" 4360.000000 #######
#     7.                 "LowGrayLevelEmphasis" 4359.000000 #######
#     8.                    "GrayLevelVariance" 4166.000000 ######
#     9.  "LargeDependenceLowGrayLevelEmphasis" 4085.000000 ######
#    10.              "SmallDependenceEmphasis" 3723.000000 ####
#    11.                   "DependenceVariance" 3718.000000 ####
#    12.              "LargeDependenceEmphasis" 3193.000000 #
#    13.              "DependenceNonUniformity" 3022.000000
#    14.    "DependenceNonUniformityNormalized" 2955.000000
#
# Variable Importance: SUM_SCORE:
#     1.                "HighGrayLevelEmphasis" 726606.515586 ################
#     2. "LargeDependenceHighGrayLevelEmphasis" 434687.247328 #########
#     3. "SmallDependenceHighGrayLevelEmphasis" 322910.219656 ######
#     4.                 "LowGrayLevelEmphasis" 319073.414155 ######
#     5.                    "DependenceEntropy" 188371.358008 ###
#     6.  "SmallDependenceLowGrayLevelEmphasis" 142093.031444 ##
#     7.  "LargeDependenceLowGrayLevelEmphasis" 127498.176478 #
#     8.               "GrayLevelNonUniformity" 110607.529350 #
#     9.                    "GrayLevelVariance" 76350.866467
#    10.                   "DependenceVariance" 74565.928494
#    11.              "SmallDependenceEmphasis" 61219.776167
#    12.              "DependenceNonUniformity" 60870.714849
#    13.    "DependenceNonUniformityNormalized" 59850.384260
#    14.              "LargeDependenceEmphasis" 55445.843987
#
#
#
# Winner takes all: true
# Out-of-bag evaluation: accuracy:0.875798 logloss:0.454364
# Number of trees: 300
# Total number of nodes: 121462
#
# Number of nodes by tree:
# Count: 300 Average: 404.873 StdDev: 18.0797
# Min: 355 Max: 459 Ignored: 0
# ----------------------------------------------
# [ 355, 360)  2   0.67%   0.67%
# [ 360, 365)  0   0.00%   0.67%
# [ 365, 370)  9   3.00%   3.67% ##
# [ 370, 376)  4   1.33%   5.00% #
# [ 376, 381)  8   2.67%   7.67% ##
# [ 381, 386) 21   7.00%  14.67% #####
# [ 386, 391) 13   4.33%  19.00% ###
# [ 391, 397) 41  13.67%  32.67% ##########
# [ 397, 402) 39  13.00%  45.67% ##########
# [ 402, 407) 24   8.00%  53.67% ######
# [ 407, 412) 36  12.00%  65.67% #########
# [ 412, 418) 30  10.00%  75.67% #######
# [ 418, 423) 23   7.67%  83.33% ######
# [ 423, 428) 19   6.33%  89.67% #####
# [ 428, 433) 12   4.00%  93.67% ###
# [ 433, 439)  9   3.00%  96.67% ##
# [ 439, 444)  3   1.00%  97.67% #
# [ 444, 449)  3   1.00%  98.67% #
# [ 449, 454)  3   1.00%  99.67% #
# [ 454, 459]  1   0.33% 100.00%
#
# Depth by leafs:
# Count: 60881 Average: 9.88684 StdDev: 2.72051
# Min: 2 Max: 15 Ignored: 0
# ----------------------------------------------
# [  2,  3)    6   0.01%   0.01%
# [  3,  4)  204   0.34%   0.34%
# [  4,  5)  782   1.28%   1.63% #
# [  5,  6) 1991   3.27%   4.90% ##
# [  6,  7) 3743   6.15%  11.05% #####
# [  7,  8) 5777   9.49%  20.54% #######
# [  8,  9) 7387  12.13%  32.67% #########
# [  9, 10) 8009  13.16%  45.83% ##########
# [ 10, 11) 8027  13.18%  59.01% ##########
# [ 11, 12) 7324  12.03%  71.04% #########
# [ 12, 13) 6087  10.00%  81.04% ########
# [ 13, 14) 4718   7.75%  88.79% ######
# [ 14, 15) 3462   5.69%  94.47% ####
# [ 15, 15] 3364   5.53% 100.00% ####
#
# Number of training obs by leaf:
# Count: 60881 Average: 68.6815 StdDev: 297.718
# Min: 5 Max: 5726 Ignored: 0
# ----------------------------------------------
# [    5,  291) 58230  95.65%  95.65% ##########
# [  291,  577)  1169   1.92%  97.57%
# [  577,  863)   401   0.66%  98.22%
# [  863, 1149)   232   0.38%  98.61%
# [ 1149, 1435)   161   0.26%  98.87%
# [ 1435, 1721)   123   0.20%  99.07%
# [ 1721, 2007)   160   0.26%  99.33%
# [ 2007, 2293)    71   0.12%  99.45%
# [ 2293, 2579)    73   0.12%  99.57%
# [ 2579, 2866)    78   0.13%  99.70%
# [ 2866, 3152)    53   0.09%  99.79%
# [ 3152, 3438)    29   0.05%  99.83%
# [ 3438, 3724)    40   0.07%  99.90%
# [ 3724, 4010)    21   0.03%  99.93%
# [ 4010, 4296)    12   0.02%  99.95%
# [ 4296, 4582)    12   0.02%  99.97%
# [ 4582, 4868)     8   0.01%  99.99%
# [ 4868, 5154)     2   0.00%  99.99%
# [ 5154, 5440)     3   0.00% 100.00%
# [ 5440, 5726]     3   0.00% 100.00%
#
# Attribute in nodes:
# 	5956 : DependenceEntropy [NUMERICAL]
# 	5707 : LargeDependenceHighGrayLevelEmphasis [NUMERICAL]
# 	5545 : HighGrayLevelEmphasis [NUMERICAL]
# 	5117 : SmallDependenceHighGrayLevelEmphasis [NUMERICAL]
# 	4675 : GrayLevelNonUniformity [NUMERICAL]
# 	4360 : SmallDependenceLowGrayLevelEmphasis [NUMERICAL]
# 	4359 : LowGrayLevelEmphasis [NUMERICAL]
# 	4166 : GrayLevelVariance [NUMERICAL]
# 	4085 : LargeDependenceLowGrayLevelEmphasis [NUMERICAL]
# 	3723 : SmallDependenceEmphasis [NUMERICAL]
# 	3718 : DependenceVariance [NUMERICAL]
# 	3193 : LargeDependenceEmphasis [NUMERICAL]
# 	3022 : DependenceNonUniformity [NUMERICAL]
# 	2955 : DependenceNonUniformityNormalized [NUMERICAL]
#
# Attribute in nodes with depth <= 0:
# 	117 : HighGrayLevelEmphasis [NUMERICAL]
# 	60 : LowGrayLevelEmphasis [NUMERICAL]
# 	54 : SmallDependenceHighGrayLevelEmphasis [NUMERICAL]
# 	33 : LargeDependenceHighGrayLevelEmphasis [NUMERICAL]
# 	16 : LargeDependenceLowGrayLevelEmphasis [NUMERICAL]
# 	11 : SmallDependenceLowGrayLevelEmphasis [NUMERICAL]
# 	4 : DependenceEntropy [NUMERICAL]
# 	3 : GrayLevelNonUniformity [NUMERICAL]
# 	1 : LargeDependenceEmphasis [NUMERICAL]
# 	1 : DependenceNonUniformity [NUMERICAL]
#
# Attribute in nodes with depth <= 1:
# 	270 : HighGrayLevelEmphasis [NUMERICAL]
# 	164 : LargeDependenceHighGrayLevelEmphasis [NUMERICAL]
# 	154 : LowGrayLevelEmphasis [NUMERICAL]
# 	100 : SmallDependenceHighGrayLevelEmphasis [NUMERICAL]
# 	79 : SmallDependenceLowGrayLevelEmphasis [NUMERICAL]
# 	37 : LargeDependenceLowGrayLevelEmphasis [NUMERICAL]
# 	23 : DependenceEntropy [NUMERICAL]
# 	19 : GrayLevelNonUniformity [NUMERICAL]
# 	15 : DependenceNonUniformity [NUMERICAL]
# 	14 : DependenceNonUniformityNormalized [NUMERICAL]
# 	11 : SmallDependenceEmphasis [NUMERICAL]
# 	7 : GrayLevelVariance [NUMERICAL]
# 	5 : DependenceVariance [NUMERICAL]
# 	2 : LargeDependenceEmphasis [NUMERICAL]
#
# Attribute in nodes with depth <= 2:
# 	523 : HighGrayLevelEmphasis [NUMERICAL]
# 	378 : LargeDependenceHighGrayLevelEmphasis [NUMERICAL]
# 	278 : LowGrayLevelEmphasis [NUMERICAL]
# 	183 : DependenceEntropy [NUMERICAL]
# 	179 : SmallDependenceHighGrayLevelEmphasis [NUMERICAL]
# 	161 : SmallDependenceLowGrayLevelEmphasis [NUMERICAL]
# 	98 : LargeDependenceLowGrayLevelEmphasis [NUMERICAL]
# 	91 : GrayLevelNonUniformity [NUMERICAL]
# 	51 : GrayLevelVariance [NUMERICAL]
# 	38 : DependenceVariance [NUMERICAL]
# 	31 : DependenceNonUniformity [NUMERICAL]
# 	28 : LargeDependenceEmphasis [NUMERICAL]
# 	28 : DependenceNonUniformityNormalized [NUMERICAL]
# 	27 : SmallDependenceEmphasis [NUMERICAL]
#
# Attribute in nodes with depth <= 3:
# 	853 : HighGrayLevelEmphasis [NUMERICAL]
# 	727 : LargeDependenceHighGrayLevelEmphasis [NUMERICAL]
# 	489 : DependenceEntropy [NUMERICAL]
# 	452 : LowGrayLevelEmphasis [NUMERICAL]
# 	325 : SmallDependenceHighGrayLevelEmphasis [NUMERICAL]
# 	282 : SmallDependenceLowGrayLevelEmphasis [NUMERICAL]
# 	266 : GrayLevelNonUniformity [NUMERICAL]
# 	214 : LargeDependenceLowGrayLevelEmphasis [NUMERICAL]
# 	172 : GrayLevelVariance [NUMERICAL]
# 	130 : DependenceVariance [NUMERICAL]
# 	98 : SmallDependenceEmphasis [NUMERICAL]
# 	95 : LargeDependenceEmphasis [NUMERICAL]
# 	95 : DependenceNonUniformity [NUMERICAL]
# 	80 : DependenceNonUniformityNormalized [NUMERICAL]
#
# Attribute in nodes with depth <= 5:
# 	1768 : HighGrayLevelEmphasis [NUMERICAL]
# 	1636 : LargeDependenceHighGrayLevelEmphasis [NUMERICAL]
# 	1486 : DependenceEntropy [NUMERICAL]
# 	1089 : LowGrayLevelEmphasis [NUMERICAL]
# 	1081 : SmallDependenceHighGrayLevelEmphasis [NUMERICAL]
# 	1014 : GrayLevelNonUniformity [NUMERICAL]
# 	853 : SmallDependenceLowGrayLevelEmphasis [NUMERICAL]
# 	758 : LargeDependenceLowGrayLevelEmphasis [NUMERICAL]
# 	742 : GrayLevelVariance [NUMERICAL]
# 	605 : DependenceVariance [NUMERICAL]
# 	567 : SmallDependenceEmphasis [NUMERICAL]
# 	532 : LargeDependenceEmphasis [NUMERICAL]
# 	468 : DependenceNonUniformity [NUMERICAL]
# 	446 : DependenceNonUniformityNormalized [NUMERICAL]
#
# Condition type in nodes:
# 	60581 : HigherCondition
# Condition type in nodes with depth <= 0:
# 	300 : HigherCondition
# Condition type in nodes with depth <= 1:
# 	900 : HigherCondition
# Condition type in nodes with depth <= 2:
# 	2094 : HigherCondition
# Condition type in nodes with depth <= 3:
# 	4278 : HigherCondition
# Condition type in nodes with depth <= 5:
# 	13045 : HigherCondition
# Node format: NOT_SET
#
# Training OOB:
# 	trees: 1, Out-of-bag evaluation: accuracy:0.860958 logloss:5.01158
# 	trees: 11, Out-of-bag evaluation: accuracy:0.861916 logloss:2.23865
# 	trees: 21, Out-of-bag evaluation: accuracy:0.864805 logloss:1.37936
# 	trees: 31, Out-of-bag evaluation: accuracy:0.86959 logloss:1.04992
# 	trees: 41, Out-of-bag evaluation: accuracy:0.871062 logloss:0.955103
# 	trees: 51, Out-of-bag evaluation: accuracy:0.871331 logloss:0.82515
# 	trees: 61, Out-of-bag evaluation: accuracy:0.873782 logloss:0.751421
# 	trees: 71, Out-of-bag evaluation: accuracy:0.873936 logloss:0.714143
# 	trees: 81, Out-of-bag evaluation: accuracy:0.875216 logloss:0.695003
# 	trees: 91, Out-of-bag evaluation: accuracy:0.877821 logloss:0.656215
# 	trees: 101, Out-of-bag evaluation: accuracy:0.875958 logloss:0.653304
# 	trees: 111, Out-of-bag evaluation: accuracy:0.877898 logloss:0.634903
# 	trees: 121, Out-of-bag evaluation: accuracy:0.875485 logloss:0.616606
# 	trees: 131, Out-of-bag evaluation: accuracy:0.874205 logloss:0.581947
# 	trees: 141, Out-of-bag evaluation: accuracy:0.876419 logloss:0.580596
# 	trees: 151, Out-of-bag evaluation: accuracy:0.876266 logloss:0.562587
# 	trees: 161, Out-of-bag evaluation: accuracy:0.876887 logloss:0.544089
# 	trees: 171, Out-of-bag evaluation: accuracy:0.876573 logloss:0.544257
# 	trees: 182, Out-of-bag evaluation: accuracy:0.875331 logloss:0.526841
# 	trees: 192, Out-of-bag evaluation: accuracy:0.874825 logloss:0.509978
# 	trees: 202, Out-of-bag evaluation: accuracy:0.873155 logloss:0.491944
# 	trees: 212, Out-of-bag evaluation: accuracy:0.875798 logloss:0.491773
# 	trees: 222, Out-of-bag evaluation: accuracy:0.875178 logloss:0.491536
# 	trees: 232, Out-of-bag evaluation: accuracy:0.876381 logloss:0.490324
# 	trees: 242, Out-of-bag evaluation: accuracy:0.876963 logloss:0.473567
# 	trees: 252, Out-of-bag evaluation: accuracy:0.876227 logloss:0.47301
# 	trees: 262, Out-of-bag evaluation: accuracy:0.877431 logloss:0.471973
# 	trees: 272, Out-of-bag evaluation: accuracy:0.875722 logloss:0.455379
# 	trees: 282, Out-of-bag evaluation: accuracy:0.87681 logloss:0.455252
# 	trees: 292, Out-of-bag evaluation: accuracy:0.876381 logloss:0.45359
# 	trees: 300, Out-of-bag evaluation: accuracy:0.875798 logloss:0.454364

# %%
# Model features
model.make_inspector().features()
# Out:
# ["DependenceEntropy" (1; #0),
#  "DependenceNonUniformity" (1; #1),
#  "DependenceNonUniformityNormalized" (1; #2),
#  "DependenceVariance" (1; #3),
#  "GrayLevelNonUniformity" (1; #4),
#  "GrayLevelVariance" (1; #5),
#  "HighGrayLevelEmphasis" (1; #6),
#  "LargeDependenceEmphasis" (1; #7),
#  "LargeDependenceHighGrayLevelEmphasis" (1; #8),
#  "LargeDependenceLowGrayLevelEmphasis" (1; #9),
#  "LowGrayLevelEmphasis" (1; #10),
#  "SmallDependenceEmphasis" (1; #11),
#  "SmallDependenceHighGrayLevelEmphasis" (1; #12),
#  "SmallDependenceLowGrayLevelEmphasis" (1; #13)]

# %%
# Feature importance
model.make_inspector().variable_importances()
# Out:
# {'INV_MEAN_MIN_DEPTH': [("HighGrayLevelEmphasis" (1; #6), 0.28065043168081355),
#   ("LargeDependenceHighGrayLevelEmphasis" (1; #8), 0.22035481801693554),
#   ("LowGrayLevelEmphasis" (1; #10), 0.1598132457705228),
#   ("SmallDependenceHighGrayLevelEmphasis" (1; #12), 0.15517015119688252),
#   ("DependenceEntropy" (1; #0), 0.15385372987995788),
#   ("SmallDependenceLowGrayLevelEmphasis" (1; #13), 0.13190443306349145),
#   ("LargeDependenceLowGrayLevelEmphasis" (1; #9), 0.12062001425766469),
#   ("GrayLevelNonUniformity" (1; #4), 0.11919010491579399),
#   ("DependenceVariance" (1; #3), 0.11077038407278647),
#   ("GrayLevelVariance" (1; #5), 0.11056042425736853),
#   ("DependenceNonUniformity" (1; #1), 0.10737455652784574),
#   ("SmallDependenceEmphasis" (1; #11), 0.10683257706991486),
#   ("DependenceNonUniformityNormalized" (1; #2), 0.10655177244001172),
#   ("LargeDependenceEmphasis" (1; #7), 0.10595850683695783)],
#  'NUM_AS_ROOT': [("HighGrayLevelEmphasis" (1; #6), 117.0),
#   ("LowGrayLevelEmphasis" (1; #10), 60.0),
#   ("SmallDependenceHighGrayLevelEmphasis" (1; #12), 54.0),
#   ("LargeDependenceHighGrayLevelEmphasis" (1; #8), 33.0),
#   ("LargeDependenceLowGrayLevelEmphasis" (1; #9), 16.0),
#   ("SmallDependenceLowGrayLevelEmphasis" (1; #13), 11.0),
#   ("DependenceEntropy" (1; #0), 4.0),
#   ("GrayLevelNonUniformity" (1; #4), 3.0),
#   ("DependenceNonUniformity" (1; #1), 1.0),
#   ("LargeDependenceEmphasis" (1; #7), 1.0)],
#  'SUM_SCORE': [("HighGrayLevelEmphasis" (1; #6), 726606.5155860439),
#   ("LargeDependenceHighGrayLevelEmphasis" (1; #8), 434687.2473281756),
#   ("SmallDependenceHighGrayLevelEmphasis" (1; #12), 322910.21965598466),
#   ("LowGrayLevelEmphasis" (1; #10), 319073.414154571),
#   ("DependenceEntropy" (1; #0), 188371.35800808461),
#   ("SmallDependenceLowGrayLevelEmphasis" (1; #13), 142093.03144399278),
#   ("LargeDependenceLowGrayLevelEmphasis" (1; #9), 127498.17647843111),
#   ("GrayLevelNonUniformity" (1; #4), 110607.52935046797),
#   ("GrayLevelVariance" (1; #5), 76350.86646730456),
#   ("DependenceVariance" (1; #3), 74565.92849436215),
#   ("SmallDependenceEmphasis" (1; #11), 61219.776166970194),
#   ("DependenceNonUniformity" (1; #1), 60870.71484880116),
#   ("DependenceNonUniformityNormalized" (1; #2), 59850.38425992773),
#   ("LargeDependenceEmphasis" (1; #7), 55445.84398731469)],
#  'NUM_NODES': [("DependenceEntropy" (1; #0), 5956.0),
#   ("LargeDependenceHighGrayLevelEmphasis" (1; #8), 5707.0),
#   ("HighGrayLevelEmphasis" (1; #6), 5545.0),
#   ("SmallDependenceHighGrayLevelEmphasis" (1; #12), 5117.0),
#   ("GrayLevelNonUniformity" (1; #4), 4675.0),
#   ("SmallDependenceLowGrayLevelEmphasis" (1; #13), 4360.0),
#   ("LowGrayLevelEmphasis" (1; #10), 4359.0),
#   ("GrayLevelVariance" (1; #5), 4166.0),
#   ("LargeDependenceLowGrayLevelEmphasis" (1; #9), 4085.0),
#   ("SmallDependenceEmphasis" (1; #11), 3723.0),
#   ("DependenceVariance" (1; #3), 3718.0),
#   ("LargeDependenceEmphasis" (1; #7), 3193.0),
#   ("DependenceNonUniformity" (1; #1), 3022.0),
#   ("DependenceNonUniformityNormalized" (1; #2), 2955.0)]}

# %%
# Model self evaluation
model.make_inspector().evaluation()
# Out:
# Evaluation(num_examples=13938, accuracy=0.87579841729168, loss=0.4543639343344479, rmse=None, ndcg=None, aucs=None, auuc=None, qini=None)

# %%
logs = model.make_inspector().training_logs()

plt.figure(figsize=(12, 4))
plt.subplot(1, 2, 1)
plt.plot([log.num_trees for log in logs], [log.evaluation.accuracy for log in logs])
plt.xlabel("Number of trees")
plt.ylabel("Accuracy (out-of-bag)")
plt.subplot(1, 2, 2)
plt.plot([log.num_trees for log in logs], [log.evaluation.loss for log in logs])
plt.xlabel("Number of trees")
plt.ylabel("Logloss (out-of-bag)")
plt.show()

# %% [markdown]
# Calculate the score of our hold-out validation dataset

# %%
predictions = model.predict(val_ds)
y_true      = validation_data["label"]

from sklearn.metrics import roc_auc_score
ROC_AUC = roc_auc_score(y_true, predictions)
print("The ROC AUC score is %.5f" % ROC_AUC )
# Out:
# 1/2 [==============>...............] - ETA: 0s
# 2/2 [==============================] - 0s 15ms/step
# The ROC AUC score is 0.99789

# %%
# Compute binary classification metrics with sklearn
import numpy as np
from sklearn.metrics import (
    accuracy_score,
    precision_score,
    recall_score,
    f1_score,
    roc_auc_score,
    average_precision_score,
    confusion_matrix,
    classification_report,
    matthews_corrcoef,
    log_loss,
    brier_score_loss,
)

# Get predictions (probabilities or class labels)
preds = model.predict(test_ds)
# If model outputs probabilities, convert to labels by threshold 0.5
if preds.ndim == 2:
    # For TFDF classification, preds may be class probabilities with shape (N, 2)
    if preds.shape[1] == 2:
        pos_probs = preds[:, 1]
    else:
        # If single-probability column (positive class)
        pos_probs = preds[:, -1]
    y_pred = (pos_probs >= 0.5).astype(int)
else:
    # Already class labels
    y_pred = preds.astype(int)
    pos_probs = None

# Ground truth labels (must be 0/1 integers)
y_true = test_data["label"].astype(int).to_numpy()

# Core metrics
metrics = {}
metrics["accuracy"] = accuracy_score(y_true, y_pred)
metrics["precision"] = precision_score(y_true, y_pred, zero_division=0)
metrics["recall"] = recall_score(y_true, y_pred, zero_division=0)
metrics["f1"] = f1_score(y_true, y_pred, zero_division=0)
metrics["mcc"] = matthews_corrcoef(y_true, y_pred)

# Probabilistic metrics (only if we have probabilities)
if pos_probs is not None:
    metrics["roc_auc"] = roc_auc_score(y_true, pos_probs)
    metrics["pr_auc"] = average_precision_score(y_true, pos_probs)
    metrics["log_loss"] = log_loss(y_true, pos_probs, labels=[0,1])
    metrics["brier_score"] = brier_score_loss(y_true, pos_probs)

# Confusion matrix and detailed report
cm = confusion_matrix(y_true, y_pred, labels=[0,1])
report = classification_report(y_true, y_pred, digits=4)

print("Sklearn binary metrics:")
for k, v in metrics.items():
    print(f"{k}: {v:.4f}")
print("\nConfusion matrix:\n", cm)
print("\nClassification report:\n", report)
# Out:
# 1/5 [=====>........................] - ETA: 0s
# 5/5 [==============================] - 0s 11ms/step
# Sklearn binary metrics:
# accuracy: 0.9620
# precision: 0.8476
# recall: 0.7463
# f1: 0.7938
# mcc: 0.7748
# roc_auc: 0.9631
# pr_auc: 0.8693
# log_loss: 0.1218
# brier_score: 0.0285
#
# Confusion matrix:
#  [[3714   55]
#  [ 104  306]]
#
# Classification report:
#                precision    recall  f1-score   support
#
#            0     0.9728    0.9854    0.9790      3769
#            1     0.8476    0.7463    0.7938       410
#
#     accuracy                         0.9620      4179
#    macro avg     0.9102    0.8659    0.8864      4179
# weighted avg     0.9605    0.9620    0.9609      4179
