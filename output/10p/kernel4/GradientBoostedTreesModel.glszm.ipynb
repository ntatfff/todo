# %%
# Import packages and modules
import numpy  as np
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow_decision_forests as tfdf

from sklearn.model_selection import train_test_split
# Out:
# 2026-09-11 08:13:05.803840: I tensorflow/core/util/port.cc:113] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2026-09-11 08:13:05.853404: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2026-09-11 08:13:11.152066: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
# Check the version of TensorFlow Decision Forests
print("Found TensorFlow Decision Forests v" + tfdf.__version__)
# Out:
# Found TensorFlow Decision Forests v1.9.1

# %%
datasetPath = "dataset/10p/all/kernel3/"

# %%
# Parameters
datasetPath = "dataset/10p/glszm/kernel4/"

# %%
# train/validation/test = 70/10/20
train_data = pd.read_csv(f"{datasetPath}dataset.train.csv")
validation_data = pd.read_csv(f"{datasetPath}dataset.validation.csv")
test_data = pd.read_csv(f"{datasetPath}dataset.test.csv")

# %%
from sklearn.utils.class_weight import compute_class_weight

# tinh class weight tren tap train
classes = np.array([0, 1])
weights = compute_class_weight(class_weight="balanced", classes=classes, y=train_data["label"])
class_weight = {0: weights[0], 1: weights[1]}

# gan sample_weight cho tung dong
train_data["sample_weight"] = train_data["label"].map(class_weight)
validation_data["sample_weight"] = validation_data["label"].map(class_weight)
test_data["sample_weight"] = test_data["label"].map(class_weight)

# Convert the dataset into a TensorFlow dataset.
train_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    train_data, label="label", weight="sample_weight"
)         
val_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    validation_data, label="label", weight="sample_weight"
)
test_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    test_data, label="label", weight="sample_weight"
)
# Out:
# 2026-09-11 08:13:26.849045: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:984] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2026-09-11 08:13:26.850757: W tensorflow/core/common_runtime/gpu/gpu_device.cc:2251] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...

# %%
import keras

# %%
# %%time

# Train a Gradient Boosted Trees model.
model = tfdf.keras.GradientBoostedTreesModel()

# Add evaluation metrics
model.compile(
    metrics=["accuracy"]
)
model.fit(x=train_ds)

# # Train a Gradient Boosted Trees model.
# model = tfdf.keras.GradientBoostedTreesModel(num_trees=1500)
# model.fit(train_ds)
# Out:
# Use /tmp/tmpcaem5kyx as temporary training directory
# Reading training dataset...
# [WARNING 26-09-11 08:13:26.9772 UTC gradient_boosted_trees.cc:1840] "goss_alpha" set but "sampling_method" not equal to "GOSS".
# [WARNING 26-09-11 08:13:26.9772 UTC gradient_boosted_trees.cc:1851] "goss_beta" set but "sampling_method" not equal to "GOSS".
# [WARNING 26-09-11 08:13:26.9772 UTC gradient_boosted_trees.cc:1865] "selective_gradient_boosting_ratio" set but "sampling_method" not equal to "SELGB".
# Training dataset read in 0:00:03.240003. Found 13938 examples.
# Training model...
# Model trained in 0:00:01.354348
# Compiling model...
# [INFO 26-09-11 08:13:31.5970 UTC kernel.cc:1233] Loading model from path /tmp/tmpcaem5kyx/model/ with prefix 17ae6dc3bf0e438b
# [INFO 26-09-11 08:13:31.6006 UTC quick_scorer_extended.cc:911] The binary was compiled without AVX2 support, but your CPU supports it. Enable it for faster model inference.
# [INFO 26-09-11 08:13:31.6008 UTC abstract_model.cc:1362] Engine "GradientBoostedTreesQuickScorerExtended" built
# [INFO 26-09-11 08:13:31.6008 UTC kernel.cc:1061] Use fast generic engine
# Model compiled.
# CPU times: user 13.6 s, sys: 703 ms, total: 14.3 s
# Wall time: 8.5 s

# %%
# Evaluate the model
evaluate = model.evaluate(val_ds, return_dict=True)
print()

for name, value in evaluate.items():
    print(f"{name}: {value:.4f}")
# Out:
# WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 1/2 [==============>...............] - ETA: 3s - loss: 0.0000e+00 - accuracy: 0.9680
# 2/2 [==============================] - 4s 13ms/step - loss: 0.0000e+00 - accuracy: 0.9651
# loss: 0.0000
# accuracy: 0.9651

# %%
# Model Summary
model.summary()
# Out:
# Model: "gradient_boosted_trees_model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
# =================================================================
# Total params: 1 (1.00 Byte)
# Trainable params: 0 (0.00 Byte)
# Non-trainable params: 1 (1.00 Byte)
# _________________________________________________________________
# Type: "GRADIENT_BOOSTED_TREES"
# Task: CLASSIFICATION
# Label: "__LABEL"
#
# Input Features (16):
# 	GrayLevelNonUniformity
# 	GrayLevelNonUniformityNormalized
# 	GrayLevelVariance
# 	HighGrayLevelZoneEmphasis
# 	LargeAreaEmphasis
# 	LargeAreaHighGrayLevelEmphasis
# 	LargeAreaLowGrayLevelEmphasis
# 	LowGrayLevelZoneEmphasis
# 	SizeZoneNonUniformity
# 	SizeZoneNonUniformityNormalized
# 	SmallAreaEmphasis
# 	SmallAreaHighGrayLevelEmphasis
# 	SmallAreaLowGrayLevelEmphasis
# 	ZoneEntropy
# 	ZonePercentage
# 	ZoneVariance
#
# Trained with weights
#
# Variable Importance: INV_MEAN_MIN_DEPTH:
#     1.        "HighGrayLevelZoneEmphasis"  0.339769 ################
#     2.   "LargeAreaHighGrayLevelEmphasis"  0.264660 ########
#     3.           "GrayLevelNonUniformity"  0.229757 #####
#     4.    "LargeAreaLowGrayLevelEmphasis"  0.229429 #####
#     5.   "SmallAreaHighGrayLevelEmphasis"  0.190422 #
#     6.         "LowGrayLevelZoneEmphasis"  0.188694 #
#     7.                     "ZoneVariance"  0.185699 #
#     8.                      "ZoneEntropy"  0.185545 #
#     9.    "SmallAreaLowGrayLevelEmphasis"  0.183465
#    10. "GrayLevelNonUniformityNormalized"  0.181812
#    11.  "SizeZoneNonUniformityNormalized"  0.181687
#    12.                "SmallAreaEmphasis"  0.181584
#    13.                "GrayLevelVariance"  0.180597
#    14.                "LargeAreaEmphasis"  0.176484
#    15.                   "ZonePercentage"  0.175207
#    16.            "SizeZoneNonUniformity"  0.173616
#
# Variable Importance: NUM_AS_ROOT:
#     1.       "HighGrayLevelZoneEmphasis" 38.000000 ################
#     2.  "LargeAreaHighGrayLevelEmphasis" 14.000000 #####
#     3.   "LargeAreaLowGrayLevelEmphasis"  7.000000 ##
#     4.          "GrayLevelNonUniformity"  6.000000 ##
#     5.               "SmallAreaEmphasis"  3.000000
#     6. "SizeZoneNonUniformityNormalized"  2.000000
#     7.   "SmallAreaLowGrayLevelEmphasis"  2.000000
#     8.        "LowGrayLevelZoneEmphasis"  1.000000
#
# Variable Importance: NUM_NODES:
#     1.        "HighGrayLevelZoneEmphasis" 255.000000 ################
#     2.    "LargeAreaLowGrayLevelEmphasis" 237.000000 ##############
#     3.           "GrayLevelNonUniformity" 212.000000 ############
#     4.   "LargeAreaHighGrayLevelEmphasis" 209.000000 ############
#     5.   "SmallAreaHighGrayLevelEmphasis" 176.000000 ##########
#     6.         "LowGrayLevelZoneEmphasis" 125.000000 ######
#     7.                      "ZoneEntropy" 104.000000 #####
#     8. "GrayLevelNonUniformityNormalized" 80.000000 ###
#     9.                "GrayLevelVariance" 80.000000 ###
#    10.    "SmallAreaLowGrayLevelEmphasis" 70.000000 ##
#    11.                     "ZoneVariance" 64.000000 ##
#    12.  "SizeZoneNonUniformityNormalized" 49.000000 #
#    13.                "SmallAreaEmphasis" 44.000000
#    14.                   "ZonePercentage" 41.000000
#    15.                "LargeAreaEmphasis" 34.000000
#    16.            "SizeZoneNonUniformity" 30.000000
#
# Variable Importance: SUM_SCORE:
#     1.        "HighGrayLevelZoneEmphasis" 9184.645159 ################
#     2.   "LargeAreaHighGrayLevelEmphasis" 1459.631624 ##
#     3.           "GrayLevelNonUniformity" 1307.810380 ##
#     4.    "LargeAreaLowGrayLevelEmphasis" 719.699016 #
#     5.   "SmallAreaHighGrayLevelEmphasis" 508.500570
#     6.                      "ZoneEntropy" 433.334777
#     7.                "GrayLevelVariance" 241.487264
#     8. "GrayLevelNonUniformityNormalized" 231.556745
#     9.         "LowGrayLevelZoneEmphasis" 226.099762
#    10.                "SmallAreaEmphasis" 153.310643
#    11.  "SizeZoneNonUniformityNormalized" 123.851150
#    12.                     "ZoneVariance" 109.621402
#    13.                "LargeAreaEmphasis" 98.184578
#    14.    "SmallAreaLowGrayLevelEmphasis" 91.441755
#    15.                   "ZonePercentage" 89.181554
#    16.            "SizeZoneNonUniformity" 43.257323
#
#
#
# Loss: BINOMIAL_LOG_LIKELIHOOD
# Validation loss value: 0.432536
# Number of trees per iteration: 1
# Node format: NOT_SET
# Number of trees: 73
# Total number of nodes: 3693
#
# Number of nodes by tree:
# Count: 73 Average: 50.589 StdDev: 8.32201
# Min: 33 Max: 63 Ignored: 0
# ----------------------------------------------
# [ 33, 34)  1   1.37%   1.37% #
# [ 34, 36)  1   1.37%   2.74% #
# [ 36, 37)  0   0.00%   2.74%
# [ 37, 39)  2   2.74%   5.48% ##
# [ 39, 40)  2   2.74%   8.22% ##
# [ 40, 42)  9  12.33%  20.55% ########
# [ 42, 43)  0   0.00%  20.55%
# [ 43, 45)  3   4.11%  24.66% ###
# [ 45, 46)  7   9.59%  34.25% ######
# [ 46, 48)  7   9.59%  43.84% ######
# [ 48, 50)  6   8.22%  52.05% #####
# [ 50, 51)  0   0.00%  52.05%
# [ 51, 53)  4   5.48%  57.53% ###
# [ 53, 54)  1   1.37%  58.90% #
# [ 54, 56)  6   8.22%  67.12% #####
# [ 56, 57)  0   0.00%  67.12%
# [ 57, 59)  5   6.85%  73.97% ####
# [ 59, 60)  2   2.74%  76.71% ##
# [ 60, 62) 12  16.44%  93.15% ##########
# [ 62, 63]  5   6.85% 100.00% ####
#
# Depth by leafs:
# Count: 1883 Average: 4.84121 StdDev: 0.520183
# Min: 2 Max: 5 Ignored: 0
# ----------------------------------------------
# [ 2, 3)   25   1.33%   1.33%
# [ 3, 4)   54   2.87%   4.20%
# [ 4, 5)  116   6.16%  10.36% #
# [ 5, 5] 1688  89.64% 100.00% ##########
#
# Number of training obs by leaf:
# Count: 1883 Average: 486.189 StdDev: 1313.18
# Min: 5 Max: 12059 Ignored: 0
# ----------------------------------------------
# [     5,   607) 1592  84.55%  84.55% ##########
# [   607,  1210)  114   6.05%  90.60% #
# [  1210,  1813)   48   2.55%  93.15%
# [  1813,  2416)   30   1.59%  94.74%
# [  2416,  3018)   13   0.69%  95.43%
# [  3018,  3621)   15   0.80%  96.23%
# [  3621,  4224)   10   0.53%  96.76%
# [  4224,  4827)    9   0.48%  97.24%
# [  4827,  5429)   11   0.58%  97.82%
# [  5429,  6032)    9   0.48%  98.30%
# [  6032,  6635)    6   0.32%  98.62%
# [  6635,  7238)    7   0.37%  98.99%
# [  7238,  7840)    6   0.32%  99.31%
# [  7840,  8443)    5   0.27%  99.58%
# [  8443,  9046)    2   0.11%  99.68%
# [  9046,  9649)    1   0.05%  99.73%
# [  9649, 10251)    0   0.00%  99.73%
# [ 10251, 10854)    2   0.11%  99.84%
# [ 10854, 11457)    1   0.05%  99.89%
# [ 11457, 12059]    2   0.11% 100.00%
#
# Attribute in nodes:
# 	255 : HighGrayLevelZoneEmphasis [NUMERICAL]
# 	237 : LargeAreaLowGrayLevelEmphasis [NUMERICAL]
# 	212 : GrayLevelNonUniformity [NUMERICAL]
# 	209 : LargeAreaHighGrayLevelEmphasis [NUMERICAL]
# 	176 : SmallAreaHighGrayLevelEmphasis [NUMERICAL]
# 	125 : LowGrayLevelZoneEmphasis [NUMERICAL]
# 	104 : ZoneEntropy [NUMERICAL]
# 	80 : GrayLevelVariance [NUMERICAL]
# 	80 : GrayLevelNonUniformityNormalized [NUMERICAL]
# 	70 : SmallAreaLowGrayLevelEmphasis [NUMERICAL]
# 	64 : ZoneVariance [NUMERICAL]
# 	49 : SizeZoneNonUniformityNormalized [NUMERICAL]
# 	44 : SmallAreaEmphasis [NUMERICAL]
# 	41 : ZonePercentage [NUMERICAL]
# 	34 : LargeAreaEmphasis [NUMERICAL]
# 	30 : SizeZoneNonUniformity [NUMERICAL]
#
# Attribute in nodes with depth <= 0:
# 	38 : HighGrayLevelZoneEmphasis [NUMERICAL]
# 	14 : LargeAreaHighGrayLevelEmphasis [NUMERICAL]
# 	7 : LargeAreaLowGrayLevelEmphasis [NUMERICAL]
# 	6 : GrayLevelNonUniformity [NUMERICAL]
# 	3 : SmallAreaEmphasis [NUMERICAL]
# 	2 : SmallAreaLowGrayLevelEmphasis [NUMERICAL]
# 	2 : SizeZoneNonUniformityNormalized [NUMERICAL]
# 	1 : LowGrayLevelZoneEmphasis [NUMERICAL]
#
# Attribute in nodes with depth <= 1:
# 	68 : HighGrayLevelZoneEmphasis [NUMERICAL]
# 	52 : LargeAreaHighGrayLevelEmphasis [NUMERICAL]
# 	26 : LargeAreaLowGrayLevelEmphasis [NUMERICAL]
# 	26 : GrayLevelNonUniformity [NUMERICAL]
# 	10 : ZoneVariance [NUMERICAL]
# 	6 : LowGrayLevelZoneEmphasis [NUMERICAL]
# 	5 : SmallAreaLowGrayLevelEmphasis [NUMERICAL]
# 	5 : SmallAreaEmphasis [NUMERICAL]
# 	5 : SizeZoneNonUniformityNormalized [NUMERICAL]
# 	4 : ZoneEntropy [NUMERICAL]
# 	4 : SmallAreaHighGrayLevelEmphasis [NUMERICAL]
# 	3 : LargeAreaEmphasis [NUMERICAL]
# 	3 : GrayLevelNonUniformityNormalized [NUMERICAL]
# 	1 : ZonePercentage [NUMERICAL]
# 	1 : GrayLevelVariance [NUMERICAL]
#
# Attribute in nodes with depth <= 2:
# 	94 : HighGrayLevelZoneEmphasis [NUMERICAL]
# 	81 : LargeAreaLowGrayLevelEmphasis [NUMERICAL]
# 	79 : LargeAreaHighGrayLevelEmphasis [NUMERICAL]
# 	68 : GrayLevelNonUniformity [NUMERICAL]
# 	21 : SmallAreaHighGrayLevelEmphasis [NUMERICAL]
# 	20 : LowGrayLevelZoneEmphasis [NUMERICAL]
# 	19 : ZoneVariance [NUMERICAL]
# 	19 : ZoneEntropy [NUMERICAL]
# 	17 : GrayLevelNonUniformityNormalized [NUMERICAL]
# 	15 : SmallAreaLowGrayLevelEmphasis [NUMERICAL]
# 	14 : SizeZoneNonUniformityNormalized [NUMERICAL]
# 	14 : GrayLevelVariance [NUMERICAL]
# 	11 : SmallAreaEmphasis [NUMERICAL]
# 	8 : LargeAreaEmphasis [NUMERICAL]
# 	4 : ZonePercentage [NUMERICAL]
# 	2 : SizeZoneNonUniformity [NUMERICAL]
#
# Attribute in nodes with depth <= 3:
# 	154 : HighGrayLevelZoneEmphasis [NUMERICAL]
# 	138 : LargeAreaLowGrayLevelEmphasis [NUMERICAL]
# 	134 : LargeAreaHighGrayLevelEmphasis [NUMERICAL]
# 	119 : GrayLevelNonUniformity [NUMERICAL]
# 	82 : SmallAreaHighGrayLevelEmphasis [NUMERICAL]
# 	61 : LowGrayLevelZoneEmphasis [NUMERICAL]
# 	54 : ZoneEntropy [NUMERICAL]
# 	44 : GrayLevelNonUniformityNormalized [NUMERICAL]
# 	36 : SmallAreaLowGrayLevelEmphasis [NUMERICAL]
# 	33 : GrayLevelVariance [NUMERICAL]
# 	32 : ZoneVariance [NUMERICAL]
# 	24 : SizeZoneNonUniformityNormalized [NUMERICAL]
# 	21 : SmallAreaEmphasis [NUMERICAL]
# 	16 : LargeAreaEmphasis [NUMERICAL]
# 	10 : ZonePercentage [NUMERICAL]
# 	8 : SizeZoneNonUniformity [NUMERICAL]
#
# Attribute in nodes with depth <= 5:
# 	255 : HighGrayLevelZoneEmphasis [NUMERICAL]
# 	237 : LargeAreaLowGrayLevelEmphasis [NUMERICAL]
# 	212 : GrayLevelNonUniformity [NUMERICAL]
# 	209 : LargeAreaHighGrayLevelEmphasis [NUMERICAL]
# 	176 : SmallAreaHighGrayLevelEmphasis [NUMERICAL]
# 	125 : LowGrayLevelZoneEmphasis [NUMERICAL]
# 	104 : ZoneEntropy [NUMERICAL]
# 	80 : GrayLevelVariance [NUMERICAL]
# 	80 : GrayLevelNonUniformityNormalized [NUMERICAL]
# 	70 : SmallAreaLowGrayLevelEmphasis [NUMERICAL]
# 	64 : ZoneVariance [NUMERICAL]
# 	49 : SizeZoneNonUniformityNormalized [NUMERICAL]
# 	44 : SmallAreaEmphasis [NUMERICAL]
# 	41 : ZonePercentage [NUMERICAL]
# 	34 : LargeAreaEmphasis [NUMERICAL]
# 	30 : SizeZoneNonUniformity [NUMERICAL]
#
# Condition type in nodes:
# 	1810 : HigherCondition
# Condition type in nodes with depth <= 0:
# 	73 : HigherCondition
# Condition type in nodes with depth <= 1:
# 	219 : HigherCondition
# Condition type in nodes with depth <= 2:
# 	486 : HigherCondition
# Condition type in nodes with depth <= 3:
# 	966 : HigherCondition
# Condition type in nodes with depth <= 5:
# 	1810 : HigherCondition
#
# Training logs:
# Number of iteration to final model: 73
# 	Iter:1 train-loss:1.249204 valid-loss:1.253040  train-accuracy:0.905678 valid-accuracy:0.887729
# 	Iter:2 train-loss:1.136467 valid-loss:1.145795  train-accuracy:0.906600 valid-accuracy:0.899091
# 	Iter:3 train-loss:1.041958 valid-loss:1.054168  train-accuracy:0.918162 valid-accuracy:0.897249
# 	Iter:4 train-loss:0.961860 valid-loss:0.977791  train-accuracy:0.919091 valid-accuracy:0.903882
# 	Iter:5 train-loss:0.893195 valid-loss:0.913192  train-accuracy:0.921971 valid-accuracy:0.908304
# 	Iter:6 train-loss:0.834985 valid-loss:0.856767  train-accuracy:0.919212 valid-accuracy:0.910515
# 	Iter:16 train-loss:0.495097 valid-loss:0.568750  train-accuracy:0.936426 valid-accuracy:0.908611
# 	Iter:26 train-loss:0.363156 valid-loss:0.479935  train-accuracy:0.943250 valid-accuracy:0.904496
# 	Iter:36 train-loss:0.299972 valid-loss:0.457159  train-accuracy:0.952018 valid-accuracy:0.912665
# 	Iter:46 train-loss:0.264254 valid-loss:0.451585  train-accuracy:0.960013 valid-accuracy:0.914876
# 	Iter:56 train-loss:0.238159 valid-loss:0.439158  train-accuracy:0.968888 valid-accuracy:0.915244
# 	Iter:66 train-loss:0.213472 valid-loss:0.436005  train-accuracy:0.972640 valid-accuracy:0.917087
# 	Iter:76 train-loss:0.196045 valid-loss:0.438286  train-accuracy:0.975655 valid-accuracy:0.918929
# 	Iter:86 train-loss:0.179195 valid-loss:0.438150  train-accuracy:0.978585 valid-accuracy:0.915183
# 	Iter:96 train-loss:0.165152 valid-loss:0.447583  train-accuracy:0.982643 valid-accuracy:0.910699

# %%
# Model features
model.make_inspector().features()
# Out:
# ["GrayLevelNonUniformity" (1; #0),
#  "GrayLevelNonUniformityNormalized" (1; #1),
#  "GrayLevelVariance" (1; #2),
#  "HighGrayLevelZoneEmphasis" (1; #3),
#  "LargeAreaEmphasis" (1; #4),
#  "LargeAreaHighGrayLevelEmphasis" (1; #5),
#  "LargeAreaLowGrayLevelEmphasis" (1; #6),
#  "LowGrayLevelZoneEmphasis" (1; #7),
#  "SizeZoneNonUniformity" (1; #8),
#  "SizeZoneNonUniformityNormalized" (1; #9),
#  "SmallAreaEmphasis" (1; #10),
#  "SmallAreaHighGrayLevelEmphasis" (1; #11),
#  "SmallAreaLowGrayLevelEmphasis" (1; #12),
#  "ZoneEntropy" (1; #13),
#  "ZonePercentage" (1; #14),
#  "ZoneVariance" (1; #15)]

# %%
# Feature importance
model.make_inspector().variable_importances()
# Out:
# {'INV_MEAN_MIN_DEPTH': [("HighGrayLevelZoneEmphasis" (1; #3),
#    0.33976927392547557),
#   ("LargeAreaHighGrayLevelEmphasis" (1; #5), 0.26466006099524964),
#   ("GrayLevelNonUniformity" (1; #0), 0.22975735756586863),
#   ("LargeAreaLowGrayLevelEmphasis" (1; #6), 0.22942909633190933),
#   ("SmallAreaHighGrayLevelEmphasis" (1; #11), 0.19042227819219296),
#   ("LowGrayLevelZoneEmphasis" (1; #7), 0.18869395970721844),
#   ("ZoneVariance" (1; #15), 0.18569881415455655),
#   ("ZoneEntropy" (1; #13), 0.1855450381268775),
#   ("SmallAreaLowGrayLevelEmphasis" (1; #12), 0.18346530935565122),
#   ("GrayLevelNonUniformityNormalized" (1; #1), 0.18181204044383378),
#   ("SizeZoneNonUniformityNormalized" (1; #9), 0.18168733430188055),
#   ("SmallAreaEmphasis" (1; #10), 0.18158383090409477),
#   ("GrayLevelVariance" (1; #2), 0.18059661514984043),
#   ("LargeAreaEmphasis" (1; #4), 0.17648440998307793),
#   ("ZonePercentage" (1; #14), 0.17520721837382192),
#   ("SizeZoneNonUniformity" (1; #8), 0.1736160465814877)],
#  'NUM_AS_ROOT': [("HighGrayLevelZoneEmphasis" (1; #3), 38.0),
#   ("LargeAreaHighGrayLevelEmphasis" (1; #5), 14.0),
#   ("LargeAreaLowGrayLevelEmphasis" (1; #6), 7.0),
#   ("GrayLevelNonUniformity" (1; #0), 6.0),
#   ("SmallAreaEmphasis" (1; #10), 3.0),
#   ("SizeZoneNonUniformityNormalized" (1; #9), 2.0),
#   ("SmallAreaLowGrayLevelEmphasis" (1; #12), 2.0),
#   ("LowGrayLevelZoneEmphasis" (1; #7), 1.0)],
#  'SUM_SCORE': [("HighGrayLevelZoneEmphasis" (1; #3), 9184.645158678177),
#   ("LargeAreaHighGrayLevelEmphasis" (1; #5), 1459.6316240694673),
#   ("GrayLevelNonUniformity" (1; #0), 1307.8103802790777),
#   ("LargeAreaLowGrayLevelEmphasis" (1; #6), 719.6990159849717),
#   ("SmallAreaHighGrayLevelEmphasis" (1; #11), 508.5005703163819),
#   ("ZoneEntropy" (1; #13), 433.33477671866603),
#   ("GrayLevelVariance" (1; #2), 241.48726353002448),
#   ("GrayLevelNonUniformityNormalized" (1; #1), 231.5567454315682),
#   ("LowGrayLevelZoneEmphasis" (1; #7), 226.0997615598689),
#   ("SmallAreaEmphasis" (1; #10), 153.31064267149944),
#   ("SizeZoneNonUniformityNormalized" (1; #9), 123.85114980080552),
#   ("ZoneVariance" (1; #15), 109.62140190005414),
#   ("LargeAreaEmphasis" (1; #4), 98.18457773626203),
#   ("SmallAreaLowGrayLevelEmphasis" (1; #12), 91.44175517823234),
#   ("ZonePercentage" (1; #14), 89.18155445211504),
#   ("SizeZoneNonUniformity" (1; #8), 43.25732314038542)],
#  'NUM_NODES': [("HighGrayLevelZoneEmphasis" (1; #3), 255.0),
#   ("LargeAreaLowGrayLevelEmphasis" (1; #6), 237.0),
#   ("GrayLevelNonUniformity" (1; #0), 212.0),
#   ("LargeAreaHighGrayLevelEmphasis" (1; #5), 209.0),
#   ("SmallAreaHighGrayLevelEmphasis" (1; #11), 176.0),
#   ("LowGrayLevelZoneEmphasis" (1; #7), 125.0),
#   ("ZoneEntropy" (1; #13), 104.0),
#   ("GrayLevelNonUniformityNormalized" (1; #1), 80.0),
#   ("GrayLevelVariance" (1; #2), 80.0),
#   ("SmallAreaLowGrayLevelEmphasis" (1; #12), 70.0),
#   ("ZoneVariance" (1; #15), 64.0),
#   ("SizeZoneNonUniformityNormalized" (1; #9), 49.0),
#   ("SmallAreaEmphasis" (1; #10), 44.0),
#   ("ZonePercentage" (1; #14), 41.0),
#   ("LargeAreaEmphasis" (1; #4), 34.0),
#   ("SizeZoneNonUniformity" (1; #8), 30.0)]}

# %%
# Model self evaluation
model.make_inspector().evaluation()
# Out:
# Evaluation(num_examples=None, accuracy=0.9178236126899719, loss=0.432535856962204, rmse=None, ndcg=None, aucs=None, auuc=None, qini=None)

# %%
logs = model.make_inspector().training_logs()

plt.figure(figsize=(12, 4))
plt.subplot(1, 2, 1)
plt.plot([log.num_trees for log in logs], [log.evaluation.accuracy for log in logs])
plt.xlabel("Number of trees")
plt.ylabel("Accuracy (out-of-bag)")
plt.subplot(1, 2, 2)
plt.plot([log.num_trees for log in logs], [log.evaluation.loss for log in logs])
plt.xlabel("Number of trees")
plt.ylabel("Logloss (out-of-bag)")
plt.show()

# %% [markdown]
# Calculate the score of our hold-out validation dataset

# %%
predictions = model.predict(val_ds)
y_true      = validation_data["label"]

from sklearn.metrics import roc_auc_score
ROC_AUC = roc_auc_score(y_true, predictions)
print("The ROC AUC score is %.5f" % ROC_AUC )
# Out:
# 1/2 [==============>...............] - ETA: 0s
# 2/2 [==============================] - 0s 5ms/step
# The ROC AUC score is 0.98947

# %%
# Compute binary classification metrics with sklearn
import numpy as np
from sklearn.metrics import (
    accuracy_score,
    precision_score,
    recall_score,
    f1_score,
    roc_auc_score,
    average_precision_score,
    confusion_matrix,
    classification_report,
    matthews_corrcoef,
    log_loss,
    brier_score_loss,
)

# Get predictions (probabilities or class labels)
preds = model.predict(test_ds)
# If model outputs probabilities, convert to labels by threshold 0.5
if preds.ndim == 2:
    # For TFDF classification, preds may be class probabilities with shape (N, 2)
    if preds.shape[1] == 2:
        pos_probs = preds[:, 1]
    else:
        # If single-probability column (positive class)
        pos_probs = preds[:, -1]
    y_pred = (pos_probs >= 0.5).astype(int)
else:
    # Already class labels
    y_pred = preds.astype(int)
    pos_probs = None

# Ground truth labels (must be 0/1 integers)
y_true = test_data["label"].astype(int).to_numpy()

# Core metrics
metrics = {}
metrics["accuracy"] = accuracy_score(y_true, y_pred)
metrics["precision"] = precision_score(y_true, y_pred, zero_division=0)
metrics["recall"] = recall_score(y_true, y_pred, zero_division=0)
metrics["f1"] = f1_score(y_true, y_pred, zero_division=0)
metrics["mcc"] = matthews_corrcoef(y_true, y_pred)

# Probabilistic metrics (only if we have probabilities)
if pos_probs is not None:
    metrics["roc_auc"] = roc_auc_score(y_true, pos_probs)
    metrics["pr_auc"] = average_precision_score(y_true, pos_probs)
    metrics["log_loss"] = log_loss(y_true, pos_probs, labels=[0,1])
    metrics["brier_score"] = brier_score_loss(y_true, pos_probs)

# Confusion matrix and detailed report
cm = confusion_matrix(y_true, y_pred, labels=[0,1])
report = classification_report(y_true, y_pred, digits=4)

print("Sklearn binary metrics:")
for k, v in metrics.items():
    print(f"{k}: {v:.4f}")
print("\nConfusion matrix:\n", cm)
print("\nClassification report:\n", report)
# Out:
# 1/5 [=====>........................] - ETA: 0s
# 5/5 [==============================] - 0s 4ms/step
# Sklearn binary metrics:
# accuracy: 0.9548
# precision: 0.7356
# recall: 0.8415
# f1: 0.7850
# mcc: 0.7620
# roc_auc: 0.9643
# pr_auc: 0.8669
# log_loss: 0.1357
# brier_score: 0.0362
#
# Confusion matrix:
#  [[3645  124]
#  [  65  345]]
#
# Classification report:
#                precision    recall  f1-score   support
#
#            0     0.9825    0.9671    0.9747      3769
#            1     0.7356    0.8415    0.7850       410
#
#     accuracy                         0.9548      4179
#    macro avg     0.8590    0.9043    0.8799      4179
# weighted avg     0.9583    0.9548    0.9561      4179
