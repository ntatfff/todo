# %%
# Import packages and modules
import numpy  as np
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow_decision_forests as tfdf

from sklearn.model_selection import train_test_split
# Out:
# 2026-09-11 08:21:31.155278: I tensorflow/core/util/port.cc:113] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2026-09-11 08:21:31.195651: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2026-09-11 08:21:35.452295: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
# Check the version of TensorFlow Decision Forests
print("Found TensorFlow Decision Forests v" + tfdf.__version__)
# Out:
# Found TensorFlow Decision Forests v1.9.1

# %%
datasetPath = "dataset/10p/all/kernel3/"

# %%
# Parameters
datasetPath = "dataset/10p/glszm/kernel4/"

# %%
# train/validation/test = 70/10/20
train_data = pd.read_csv(f"{datasetPath}dataset.train.csv")
validation_data = pd.read_csv(f"{datasetPath}dataset.validation.csv")
test_data = pd.read_csv(f"{datasetPath}dataset.test.csv")

# %%
from sklearn.utils.class_weight import compute_class_weight

# tinh class weight tren tap train
classes = np.array([0, 1])
weights = compute_class_weight(class_weight="balanced", classes=classes, y=train_data["label"])
class_weight = {0: weights[0], 1: weights[1]}

# gan sample_weight cho tung dong
train_data["sample_weight"] = train_data["label"].map(class_weight)
validation_data["sample_weight"] = validation_data["label"].map(class_weight)
test_data["sample_weight"] = test_data["label"].map(class_weight)

# Convert the dataset into a TensorFlow dataset.
train_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    train_data, label="label", weight="sample_weight"
)         
val_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    validation_data, label="label", weight="sample_weight"
)
test_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    test_data, label="label", weight="sample_weight"
)
# Out:
# 2026-09-11 08:21:48.506362: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:984] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2026-09-11 08:21:48.508111: W tensorflow/core/common_runtime/gpu/gpu_device.cc:2251] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...

# %%
import keras

# %%
# %%time

# Train a Random Forest model.
model = tfdf.keras.RandomForestModel()

# Add evaluation metrics
model.compile(
    metrics=["accuracy"]
)
model.fit(x=train_ds)

# # Train a Gradient Boosted Trees model.
# model = tfdf.keras.GradientBoostedTreesModel(num_trees=1500)
# model.fit(train_ds)
# Out:
# Use /tmp/tmpxoij78dm as temporary training directory
# Reading training dataset...
# Training dataset read in 0:00:02.516956. Found 13938 examples.
# Training model...
# Model trained in 0:00:01.083734
# Compiling model...
# [INFO 26-09-11 08:21:52.0635 UTC kernel.cc:1233] Loading model from path /tmp/tmpxoij78dm/model/ with prefix 218ae8a101974871
# [INFO 26-09-11 08:21:52.2167 UTC decision_forest.cc:734] Model loaded with 300 root(s), 129142 node(s), and 16 input feature(s).
# [INFO 26-09-11 08:21:52.2167 UTC abstract_model.cc:1362] Engine "RandomForestOptPred" built
# [INFO 26-09-11 08:21:52.2167 UTC kernel.cc:1061] Use fast generic engine
# Model compiled.
# CPU times: user 14.7 s, sys: 405 ms, total: 15.1 s
# Wall time: 6.78 s

# %%
# Evaluate the model
evaluate = model.evaluate(val_ds, return_dict=True)
print()

for name, value in evaluate.items():
    print(f"{name}: {value:.4f}")
# Out:
# WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 1/2 [==============>...............] - ETA: 2s - loss: 0.0000e+00 - accuracy: 0.9910
# 2/2 [==============================] - 3s 21ms/step - loss: 0.0000e+00 - accuracy: 0.9856
# loss: 0.0000
# accuracy: 0.9856

# %%
# Model Summary
model.summary()
# Out:
# Model: "random_forest_model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
# =================================================================
# Total params: 1 (1.00 Byte)
# Trainable params: 0 (0.00 Byte)
# Non-trainable params: 1 (1.00 Byte)
# _________________________________________________________________
# Type: "RANDOM_FOREST"
# Task: CLASSIFICATION
# Label: "__LABEL"
#
# Input Features (16):
# 	GrayLevelNonUniformity
# 	GrayLevelNonUniformityNormalized
# 	GrayLevelVariance
# 	HighGrayLevelZoneEmphasis
# 	LargeAreaEmphasis
# 	LargeAreaHighGrayLevelEmphasis
# 	LargeAreaLowGrayLevelEmphasis
# 	LowGrayLevelZoneEmphasis
# 	SizeZoneNonUniformity
# 	SizeZoneNonUniformityNormalized
# 	SmallAreaEmphasis
# 	SmallAreaHighGrayLevelEmphasis
# 	SmallAreaLowGrayLevelEmphasis
# 	ZoneEntropy
# 	ZonePercentage
# 	ZoneVariance
#
# Trained with weights
#
# Variable Importance: INV_MEAN_MIN_DEPTH:
#     1.        "HighGrayLevelZoneEmphasis"  0.215380 ################
#     2.   "SmallAreaHighGrayLevelEmphasis"  0.174333 ##########
#     3.           "GrayLevelNonUniformity"  0.165153 #########
#     4.   "LargeAreaHighGrayLevelEmphasis"  0.153020 #######
#     5.    "LargeAreaLowGrayLevelEmphasis"  0.147733 ######
#     6.         "LowGrayLevelZoneEmphasis"  0.141359 #####
#     7.    "SmallAreaLowGrayLevelEmphasis"  0.128855 ####
#     8.                      "ZoneEntropy"  0.116211 ##
#     9. "GrayLevelNonUniformityNormalized"  0.112411 #
#    10.                "GrayLevelVariance"  0.107976 #
#    11.                   "ZonePercentage"  0.106917
#    12.                "LargeAreaEmphasis"  0.103289
#    13.            "SizeZoneNonUniformity"  0.102021
#    14.                     "ZoneVariance"  0.101748
#    15.  "SizeZoneNonUniformityNormalized"  0.100654
#    16.                "SmallAreaEmphasis"  0.099856
#
# Variable Importance: NUM_AS_ROOT:
#     1.        "HighGrayLevelZoneEmphasis" 82.000000 ################
#     2.   "SmallAreaHighGrayLevelEmphasis" 71.000000 #############
#     3.         "LowGrayLevelZoneEmphasis" 45.000000 ########
#     4.    "LargeAreaLowGrayLevelEmphasis" 35.000000 ######
#     5.    "SmallAreaLowGrayLevelEmphasis" 31.000000 #####
#     6.                      "ZoneEntropy" 18.000000 ###
#     7.   "LargeAreaHighGrayLevelEmphasis" 10.000000 #
#     8. "GrayLevelNonUniformityNormalized"  6.000000
#     9.           "GrayLevelNonUniformity"  2.000000
#
# Variable Importance: NUM_NODES:
#     1.           "GrayLevelNonUniformity" 5372.000000 ################
#     2.        "HighGrayLevelZoneEmphasis" 5174.000000 ##############
#     3.   "LargeAreaHighGrayLevelEmphasis" 4951.000000 #############
#     4.    "LargeAreaLowGrayLevelEmphasis" 4922.000000 #############
#     5.   "SmallAreaHighGrayLevelEmphasis" 4846.000000 ############
#     6.         "LowGrayLevelZoneEmphasis" 4280.000000 ########
#     7.                "GrayLevelVariance" 4215.000000 ########
#     8.                      "ZoneEntropy" 4082.000000 #######
#     9.    "SmallAreaLowGrayLevelEmphasis" 3991.000000 ######
#    10. "GrayLevelNonUniformityNormalized" 3835.000000 #####
#    11.                     "ZoneVariance" 3358.000000 ##
#    12.                "LargeAreaEmphasis" 3248.000000 #
#    13.                "SmallAreaEmphasis" 3156.000000 #
#    14.                   "ZonePercentage" 3040.000000
#    15.  "SizeZoneNonUniformityNormalized" 2979.000000
#    16.            "SizeZoneNonUniformity" 2972.000000
#
# Variable Importance: SUM_SCORE:
#     1.        "HighGrayLevelZoneEmphasis" 568084.765686 ################
#     2.   "SmallAreaHighGrayLevelEmphasis" 442280.049722 ############
#     3.         "LowGrayLevelZoneEmphasis" 279738.378164 #######
#     4.           "GrayLevelNonUniformity" 231713.793573 #####
#     5.    "SmallAreaLowGrayLevelEmphasis" 212362.259975 #####
#     6.   "LargeAreaHighGrayLevelEmphasis" 205639.309373 ####
#     7.    "LargeAreaLowGrayLevelEmphasis" 198495.050557 ####
#     8.                      "ZoneEntropy" 103206.757573 #
#     9. "GrayLevelNonUniformityNormalized" 83763.793026 #
#    10.                "GrayLevelVariance" 74654.085525
#    11.                   "ZonePercentage" 63269.541508
#    12.                "LargeAreaEmphasis" 61376.388114
#    13.                     "ZoneVariance" 61212.592889
#    14.            "SizeZoneNonUniformity" 51291.386978
#    15.                "SmallAreaEmphasis" 47030.797916
#    16.  "SizeZoneNonUniformityNormalized" 46526.798418
#
#
#
# Winner takes all: true
# Out-of-bag evaluation: accuracy:0.868745 logloss:0.46108
# Number of trees: 300
# Total number of nodes: 129142
#
# Number of nodes by tree:
# Count: 300 Average: 430.473 StdDev: 22.7854
# Min: 361 Max: 487 Ignored: 0
# ----------------------------------------------
# [ 361, 367)  2   0.67%   0.67% #
# [ 367, 373)  3   1.00%   1.67% #
# [ 373, 380)  1   0.33%   2.00%
# [ 380, 386)  2   0.67%   2.67% #
# [ 386, 392)  6   2.00%   4.67% ##
# [ 392, 399) 12   4.00%   8.67% ###
# [ 399, 405) 11   3.67%  12.33% ###
# [ 405, 411) 16   5.33%  17.67% ####
# [ 411, 418) 32  10.67%  28.33% #########
# [ 418, 424) 23   7.67%  36.00% ######
# [ 424, 430) 37  12.33%  48.33% ##########
# [ 430, 437) 34  11.33%  59.67% #########
# [ 437, 443) 25   8.33%  68.00% #######
# [ 443, 449) 25   8.33%  76.33% #######
# [ 449, 456) 29   9.67%  86.00% ########
# [ 456, 462) 19   6.33%  92.33% #####
# [ 462, 468) 10   3.33%  95.67% ###
# [ 468, 475)  6   2.00%  97.67% ##
# [ 475, 481)  3   1.00%  98.67% #
# [ 481, 487]  4   1.33% 100.00% #
#
# Depth by leafs:
# Count: 64721 Average: 10.158 StdDev: 2.78179
# Min: 2 Max: 15 Ignored: 0
# ----------------------------------------------
# [  2,  3)    7   0.01%   0.01%
# [  3,  4)  233   0.36%   0.37%
# [  4,  5)  830   1.28%   1.65% #
# [  5,  6) 1983   3.06%   4.72% ##
# [  6,  7) 3570   5.52%  10.23% ####
# [  7,  8) 5407   8.35%  18.59% ######
# [  8,  9) 6891  10.65%  29.23% ########
# [  9, 10) 7926  12.25%  41.48% #########
# [ 10, 11) 8362  12.92%  54.40% ##########
# [ 11, 12) 7968  12.31%  66.71% ##########
# [ 12, 13) 6966  10.76%  77.48% ########
# [ 13, 14) 5762   8.90%  86.38% #######
# [ 14, 15) 4248   6.56%  92.94% #####
# [ 15, 15] 4568   7.06% 100.00% #####
#
# Number of training obs by leaf:
# Count: 64721 Average: 64.6065 StdDev: 250.736
# Min: 5 Max: 4556 Ignored: 0
# ----------------------------------------------
# [    5,  232) 61194  94.55%  94.55% ##########
# [  232,  460)  1541   2.38%  96.93%
# [  460,  687)   604   0.93%  97.86%
# [  687,  915)   341   0.53%  98.39%
# [  915, 1143)   227   0.35%  98.74%
# [ 1143, 1370)   163   0.25%  98.99%
# [ 1370, 1598)   140   0.22%  99.21%
# [ 1598, 1825)   146   0.23%  99.44%
# [ 1825, 2053)    99   0.15%  99.59%
# [ 2053, 2281)    72   0.11%  99.70%
# [ 2281, 2508)    52   0.08%  99.78%
# [ 2508, 2736)    34   0.05%  99.83%
# [ 2736, 2963)    27   0.04%  99.87%
# [ 2963, 3191)    27   0.04%  99.92%
# [ 3191, 3419)    17   0.03%  99.94%
# [ 3419, 3646)    12   0.02%  99.96%
# [ 3646, 3874)     7   0.01%  99.97%
# [ 3874, 4101)    10   0.02%  99.99%
# [ 4101, 4329)     5   0.01% 100.00%
# [ 4329, 4556]     3   0.00% 100.00%
#
# Attribute in nodes:
# 	5372 : GrayLevelNonUniformity [NUMERICAL]
# 	5174 : HighGrayLevelZoneEmphasis [NUMERICAL]
# 	4951 : LargeAreaHighGrayLevelEmphasis [NUMERICAL]
# 	4922 : LargeAreaLowGrayLevelEmphasis [NUMERICAL]
# 	4846 : SmallAreaHighGrayLevelEmphasis [NUMERICAL]
# 	4280 : LowGrayLevelZoneEmphasis [NUMERICAL]
# 	4215 : GrayLevelVariance [NUMERICAL]
# 	4082 : ZoneEntropy [NUMERICAL]
# 	3991 : SmallAreaLowGrayLevelEmphasis [NUMERICAL]
# 	3835 : GrayLevelNonUniformityNormalized [NUMERICAL]
# 	3358 : ZoneVariance [NUMERICAL]
# 	3248 : LargeAreaEmphasis [NUMERICAL]
# 	3156 : SmallAreaEmphasis [NUMERICAL]
# 	3040 : ZonePercentage [NUMERICAL]
# 	2979 : SizeZoneNonUniformityNormalized [NUMERICAL]
# 	2972 : SizeZoneNonUniformity [NUMERICAL]
#
# Attribute in nodes with depth <= 0:
# 	82 : HighGrayLevelZoneEmphasis [NUMERICAL]
# 	71 : SmallAreaHighGrayLevelEmphasis [NUMERICAL]
# 	45 : LowGrayLevelZoneEmphasis [NUMERICAL]
# 	35 : LargeAreaLowGrayLevelEmphasis [NUMERICAL]
# 	31 : SmallAreaLowGrayLevelEmphasis [NUMERICAL]
# 	18 : ZoneEntropy [NUMERICAL]
# 	10 : LargeAreaHighGrayLevelEmphasis [NUMERICAL]
# 	6 : GrayLevelNonUniformityNormalized [NUMERICAL]
# 	2 : GrayLevelNonUniformity [NUMERICAL]
#
# Attribute in nodes with depth <= 1:
# 	219 : HighGrayLevelZoneEmphasis [NUMERICAL]
# 	162 : SmallAreaHighGrayLevelEmphasis [NUMERICAL]
# 	119 : LowGrayLevelZoneEmphasis [NUMERICAL]
# 	91 : SmallAreaLowGrayLevelEmphasis [NUMERICAL]
# 	84 : LargeAreaHighGrayLevelEmphasis [NUMERICAL]
# 	66 : LargeAreaLowGrayLevelEmphasis [NUMERICAL]
# 	62 : GrayLevelNonUniformity [NUMERICAL]
# 	35 : ZoneEntropy [NUMERICAL]
# 	18 : ZonePercentage [NUMERICAL]
# 	17 : GrayLevelNonUniformityNormalized [NUMERICAL]
# 	11 : SizeZoneNonUniformity [NUMERICAL]
# 	7 : SizeZoneNonUniformityNormalized [NUMERICAL]
# 	4 : LargeAreaEmphasis [NUMERICAL]
# 	2 : SmallAreaEmphasis [NUMERICAL]
# 	2 : GrayLevelVariance [NUMERICAL]
# 	1 : ZoneVariance [NUMERICAL]
#
# Attribute in nodes with depth <= 2:
# 	428 : HighGrayLevelZoneEmphasis [NUMERICAL]
# 	289 : SmallAreaHighGrayLevelEmphasis [NUMERICAL]
# 	237 : LowGrayLevelZoneEmphasis [NUMERICAL]
# 	207 : GrayLevelNonUniformity [NUMERICAL]
# 	193 : LargeAreaHighGrayLevelEmphasis [NUMERICAL]
# 	181 : SmallAreaLowGrayLevelEmphasis [NUMERICAL]
# 	164 : LargeAreaLowGrayLevelEmphasis [NUMERICAL]
# 	94 : ZoneEntropy [NUMERICAL]
# 	63 : GrayLevelNonUniformityNormalized [NUMERICAL]
# 	47 : ZonePercentage [NUMERICAL]
# 	45 : GrayLevelVariance [NUMERICAL]
# 	35 : LargeAreaEmphasis [NUMERICAL]
# 	31 : ZoneVariance [NUMERICAL]
# 	30 : SizeZoneNonUniformity [NUMERICAL]
# 	26 : SizeZoneNonUniformityNormalized [NUMERICAL]
# 	23 : SmallAreaEmphasis [NUMERICAL]
#
# Attribute in nodes with depth <= 3:
# 	655 : HighGrayLevelZoneEmphasis [NUMERICAL]
# 	469 : GrayLevelNonUniformity [NUMERICAL]
# 	454 : SmallAreaHighGrayLevelEmphasis [NUMERICAL]
# 	407 : LargeAreaHighGrayLevelEmphasis [NUMERICAL]
# 	386 : LowGrayLevelZoneEmphasis [NUMERICAL]
# 	353 : LargeAreaLowGrayLevelEmphasis [NUMERICAL]
# 	341 : SmallAreaLowGrayLevelEmphasis [NUMERICAL]
# 	213 : ZoneEntropy [NUMERICAL]
# 	179 : GrayLevelVariance [NUMERICAL]
# 	169 : GrayLevelNonUniformityNormalized [NUMERICAL]
# 	131 : LargeAreaEmphasis [NUMERICAL]
# 	123 : ZonePercentage [NUMERICAL]
# 	115 : ZoneVariance [NUMERICAL]
# 	92 : SizeZoneNonUniformityNormalized [NUMERICAL]
# 	85 : SmallAreaEmphasis [NUMERICAL]
# 	74 : SizeZoneNonUniformity [NUMERICAL]
#
# Attribute in nodes with depth <= 5:
# 	1464 : HighGrayLevelZoneEmphasis [NUMERICAL]
# 	1320 : GrayLevelNonUniformity [NUMERICAL]
# 	1125 : SmallAreaHighGrayLevelEmphasis [NUMERICAL]
# 	1048 : LargeAreaHighGrayLevelEmphasis [NUMERICAL]
# 	1027 : LargeAreaLowGrayLevelEmphasis [NUMERICAL]
# 	954 : LowGrayLevelZoneEmphasis [NUMERICAL]
# 	838 : SmallAreaLowGrayLevelEmphasis [NUMERICAL]
# 	759 : ZoneEntropy [NUMERICAL]
# 	722 : GrayLevelVariance [NUMERICAL]
# 	677 : GrayLevelNonUniformityNormalized [NUMERICAL]
# 	547 : ZoneVariance [NUMERICAL]
# 	497 : LargeAreaEmphasis [NUMERICAL]
# 	482 : ZonePercentage [NUMERICAL]
# 	418 : SizeZoneNonUniformityNormalized [NUMERICAL]
# 	408 : SmallAreaEmphasis [NUMERICAL]
# 	405 : SizeZoneNonUniformity [NUMERICAL]
#
# Condition type in nodes:
# 	64421 : HigherCondition
# Condition type in nodes with depth <= 0:
# 	300 : HigherCondition
# Condition type in nodes with depth <= 1:
# 	900 : HigherCondition
# Condition type in nodes with depth <= 2:
# 	2093 : HigherCondition
# Condition type in nodes with depth <= 3:
# 	4246 : HigherCondition
# Condition type in nodes with depth <= 5:
# 	12691 : HigherCondition
# Node format: NOT_SET
#
# Training OOB:
# 	trees: 1, Out-of-bag evaluation: accuracy:0.849377 logloss:5.42899
# 	trees: 11, Out-of-bag evaluation: accuracy:0.833592 logloss:3.11454
# 	trees: 21, Out-of-bag evaluation: accuracy:0.853569 logloss:1.65561
# 	trees: 31, Out-of-bag evaluation: accuracy:0.85673 logloss:1.33831
# 	trees: 41, Out-of-bag evaluation: accuracy:0.862472 logloss:1.07446
# 	trees: 51, Out-of-bag evaluation: accuracy:0.86324 logloss:0.978908
# 	trees: 61, Out-of-bag evaluation: accuracy:0.861493 logloss:0.90036
# 	trees: 71, Out-of-bag evaluation: accuracy:0.864251 logloss:0.844875
# 	trees: 81, Out-of-bag evaluation: accuracy:0.863707 logloss:0.774082
# 	trees: 91, Out-of-bag evaluation: accuracy:0.86324 logloss:0.699347
# 	trees: 101, Out-of-bag evaluation: accuracy:0.862037 logloss:0.645318
# 	trees: 111, Out-of-bag evaluation: accuracy:0.862344 logloss:0.627355
# 	trees: 121, Out-of-bag evaluation: accuracy:0.86308 logloss:0.609238
# 	trees: 131, Out-of-bag evaluation: accuracy:0.862261 logloss:0.608364
# 	trees: 141, Out-of-bag evaluation: accuracy:0.865839 logloss:0.590347
# 	trees: 151, Out-of-bag evaluation: accuracy:0.866652 logloss:0.572643
# 	trees: 161, Out-of-bag evaluation: accuracy:0.866146 logloss:0.571911
# 	trees: 171, Out-of-bag evaluation: accuracy:0.865058 logloss:0.572332
# 	trees: 181, Out-of-bag evaluation: accuracy:0.867234 logloss:0.569565
# 	trees: 191, Out-of-bag evaluation: accuracy:0.866728 logloss:0.552402
# 	trees: 201, Out-of-bag evaluation: accuracy:0.867426 logloss:0.516465
# 	trees: 211, Out-of-bag evaluation: accuracy:0.868629 logloss:0.51681
# 	trees: 221, Out-of-bag evaluation: accuracy:0.869756 logloss:0.499317
# 	trees: 231, Out-of-bag evaluation: accuracy:0.869833 logloss:0.481712
# 	trees: 241, Out-of-bag evaluation: accuracy:0.866805 logloss:0.462546
# 	trees: 251, Out-of-bag evaluation: accuracy:0.869289 logloss:0.463117
# 	trees: 261, Out-of-bag evaluation: accuracy:0.870146 logloss:0.461262
# 	trees: 271, Out-of-bag evaluation: accuracy:0.868201 logloss:0.46174
# 	trees: 281, Out-of-bag evaluation: accuracy:0.868124 logloss:0.460789
# 	trees: 291, Out-of-bag evaluation: accuracy:0.867695 logloss:0.461111
# 	trees: 300, Out-of-bag evaluation: accuracy:0.868745 logloss:0.46108

# %%
# Model features
model.make_inspector().features()
# Out:
# ["GrayLevelNonUniformity" (1; #0),
#  "GrayLevelNonUniformityNormalized" (1; #1),
#  "GrayLevelVariance" (1; #2),
#  "HighGrayLevelZoneEmphasis" (1; #3),
#  "LargeAreaEmphasis" (1; #4),
#  "LargeAreaHighGrayLevelEmphasis" (1; #5),
#  "LargeAreaLowGrayLevelEmphasis" (1; #6),
#  "LowGrayLevelZoneEmphasis" (1; #7),
#  "SizeZoneNonUniformity" (1; #8),
#  "SizeZoneNonUniformityNormalized" (1; #9),
#  "SmallAreaEmphasis" (1; #10),
#  "SmallAreaHighGrayLevelEmphasis" (1; #11),
#  "SmallAreaLowGrayLevelEmphasis" (1; #12),
#  "ZoneEntropy" (1; #13),
#  "ZonePercentage" (1; #14),
#  "ZoneVariance" (1; #15)]

# %%
# Feature importance
model.make_inspector().variable_importances()
# Out:
# {'INV_MEAN_MIN_DEPTH': [("HighGrayLevelZoneEmphasis" (1; #3),
#    0.2153804996007764),
#   ("SmallAreaHighGrayLevelEmphasis" (1; #11), 0.17433305600651214),
#   ("GrayLevelNonUniformity" (1; #0), 0.1651532681937978),
#   ("LargeAreaHighGrayLevelEmphasis" (1; #5), 0.1530197936204349),
#   ("LargeAreaLowGrayLevelEmphasis" (1; #6), 0.14773269396479485),
#   ("LowGrayLevelZoneEmphasis" (1; #7), 0.14135856674001918),
#   ("SmallAreaLowGrayLevelEmphasis" (1; #12), 0.12885495437667457),
#   ("ZoneEntropy" (1; #13), 0.11621089664676582),
#   ("GrayLevelNonUniformityNormalized" (1; #1), 0.11241143554348627),
#   ("GrayLevelVariance" (1; #2), 0.1079755149278982),
#   ("ZonePercentage" (1; #14), 0.10691727697747856),
#   ("LargeAreaEmphasis" (1; #4), 0.10328901339710636),
#   ("SizeZoneNonUniformity" (1; #8), 0.10202098753618691),
#   ("ZoneVariance" (1; #15), 0.1017484260827426),
#   ("SizeZoneNonUniformityNormalized" (1; #9), 0.10065396762426572),
#   ("SmallAreaEmphasis" (1; #10), 0.0998556939323765)],
#  'SUM_SCORE': [("HighGrayLevelZoneEmphasis" (1; #3), 568084.7656864106),
#   ("SmallAreaHighGrayLevelEmphasis" (1; #11), 442280.0497219092),
#   ("LowGrayLevelZoneEmphasis" (1; #7), 279738.37816383684),
#   ("GrayLevelNonUniformity" (1; #0), 231713.79357278673),
#   ("SmallAreaLowGrayLevelEmphasis" (1; #12), 212362.25997452321),
#   ("LargeAreaHighGrayLevelEmphasis" (1; #5), 205639.3093731396),
#   ("LargeAreaLowGrayLevelEmphasis" (1; #6), 198495.0505566996),
#   ("ZoneEntropy" (1; #13), 103206.757573195),
#   ("GrayLevelNonUniformityNormalized" (1; #1), 83763.79302558764),
#   ("GrayLevelVariance" (1; #2), 74654.08552477165),
#   ("ZonePercentage" (1; #14), 63269.54150766715),
#   ("LargeAreaEmphasis" (1; #4), 61376.388114137764),
#   ("ZoneVariance" (1; #15), 61212.59288876802),
#   ("SizeZoneNonUniformity" (1; #8), 51291.38697776672),
#   ("SmallAreaEmphasis" (1; #10), 47030.797915656214),
#   ("SizeZoneNonUniformityNormalized" (1; #9), 46526.798418256985)],
#  'NUM_AS_ROOT': [("HighGrayLevelZoneEmphasis" (1; #3), 82.0),
#   ("SmallAreaHighGrayLevelEmphasis" (1; #11), 71.0),
#   ("LowGrayLevelZoneEmphasis" (1; #7), 45.0),
#   ("LargeAreaLowGrayLevelEmphasis" (1; #6), 35.0),
#   ("SmallAreaLowGrayLevelEmphasis" (1; #12), 31.0),
#   ("ZoneEntropy" (1; #13), 18.0),
#   ("LargeAreaHighGrayLevelEmphasis" (1; #5), 10.0),
#   ("GrayLevelNonUniformityNormalized" (1; #1), 6.0),
#   ("GrayLevelNonUniformity" (1; #0), 2.0)],
#  'NUM_NODES': [("GrayLevelNonUniformity" (1; #0), 5372.0),
#   ("HighGrayLevelZoneEmphasis" (1; #3), 5174.0),
#   ("LargeAreaHighGrayLevelEmphasis" (1; #5), 4951.0),
#   ("LargeAreaLowGrayLevelEmphasis" (1; #6), 4922.0),
#   ("SmallAreaHighGrayLevelEmphasis" (1; #11), 4846.0),
#   ("LowGrayLevelZoneEmphasis" (1; #7), 4280.0),
#   ("GrayLevelVariance" (1; #2), 4215.0),
#   ("ZoneEntropy" (1; #13), 4082.0),
#   ("SmallAreaLowGrayLevelEmphasis" (1; #12), 3991.0),
#   ("GrayLevelNonUniformityNormalized" (1; #1), 3835.0),
#   ("ZoneVariance" (1; #15), 3358.0),
#   ("LargeAreaEmphasis" (1; #4), 3248.0),
#   ("SmallAreaEmphasis" (1; #10), 3156.0),
#   ("ZonePercentage" (1; #14), 3040.0),
#   ("SizeZoneNonUniformityNormalized" (1; #9), 2979.0),
#   ("SizeZoneNonUniformity" (1; #8), 2972.0)]}

# %%
# Model self evaluation
model.make_inspector().evaluation()
# Out:
# Evaluation(num_examples=13938, accuracy=0.8687446937901087, loss=0.4610795533904465, rmse=None, ndcg=None, aucs=None, auuc=None, qini=None)

# %%
logs = model.make_inspector().training_logs()

plt.figure(figsize=(12, 4))
plt.subplot(1, 2, 1)
plt.plot([log.num_trees for log in logs], [log.evaluation.accuracy for log in logs])
plt.xlabel("Number of trees")
plt.ylabel("Accuracy (out-of-bag)")
plt.subplot(1, 2, 2)
plt.plot([log.num_trees for log in logs], [log.evaluation.loss for log in logs])
plt.xlabel("Number of trees")
plt.ylabel("Logloss (out-of-bag)")
plt.show()

# %% [markdown]
# Calculate the score of our hold-out validation dataset

# %%
predictions = model.predict(val_ds)
y_true      = validation_data["label"]

from sklearn.metrics import roc_auc_score
ROC_AUC = roc_auc_score(y_true, predictions)
print("The ROC AUC score is %.5f" % ROC_AUC )
# Out:
# 1/2 [==============>...............] - ETA: 0s
# 2/2 [==============================] - 0s 16ms/step
# The ROC AUC score is 0.99738

# %%
# Compute binary classification metrics with sklearn
import numpy as np
from sklearn.metrics import (
    accuracy_score,
    precision_score,
    recall_score,
    f1_score,
    roc_auc_score,
    average_precision_score,
    confusion_matrix,
    classification_report,
    matthews_corrcoef,
    log_loss,
    brier_score_loss,
)

# Get predictions (probabilities or class labels)
preds = model.predict(test_ds)
# If model outputs probabilities, convert to labels by threshold 0.5
if preds.ndim == 2:
    # For TFDF classification, preds may be class probabilities with shape (N, 2)
    if preds.shape[1] == 2:
        pos_probs = preds[:, 1]
    else:
        # If single-probability column (positive class)
        pos_probs = preds[:, -1]
    y_pred = (pos_probs >= 0.5).astype(int)
else:
    # Already class labels
    y_pred = preds.astype(int)
    pos_probs = None

# Ground truth labels (must be 0/1 integers)
y_true = test_data["label"].astype(int).to_numpy()

# Core metrics
metrics = {}
metrics["accuracy"] = accuracy_score(y_true, y_pred)
metrics["precision"] = precision_score(y_true, y_pred, zero_division=0)
metrics["recall"] = recall_score(y_true, y_pred, zero_division=0)
metrics["f1"] = f1_score(y_true, y_pred, zero_division=0)
metrics["mcc"] = matthews_corrcoef(y_true, y_pred)

# Probabilistic metrics (only if we have probabilities)
if pos_probs is not None:
    metrics["roc_auc"] = roc_auc_score(y_true, pos_probs)
    metrics["pr_auc"] = average_precision_score(y_true, pos_probs)
    metrics["log_loss"] = log_loss(y_true, pos_probs, labels=[0,1])
    metrics["brier_score"] = brier_score_loss(y_true, pos_probs)

# Confusion matrix and detailed report
cm = confusion_matrix(y_true, y_pred, labels=[0,1])
report = classification_report(y_true, y_pred, digits=4)

print("Sklearn binary metrics:")
for k, v in metrics.items():
    print(f"{k}: {v:.4f}")
print("\nConfusion matrix:\n", cm)
print("\nClassification report:\n", report)
# Out:
# 1/5 [=====>........................] - ETA: 0s
# 5/5 [==============================] - ETA: 0s
# 5/5 [==============================] - 0s 13ms/step
# Sklearn binary metrics:
# accuracy: 0.9596
# precision: 0.8338
# recall: 0.7341
# f1: 0.7808
# mcc: 0.7605
# roc_auc: 0.9645
# pr_auc: 0.8609
# log_loss: 0.1219
# brier_score: 0.0306
#
# Confusion matrix:
#  [[3709   60]
#  [ 109  301]]
#
# Classification report:
#                precision    recall  f1-score   support
#
#            0     0.9715    0.9841    0.9777      3769
#            1     0.8338    0.7341    0.7808       410
#
#     accuracy                         0.9596      4179
#    macro avg     0.9026    0.8591    0.8793      4179
# weighted avg     0.9579    0.9596    0.9584      4179
