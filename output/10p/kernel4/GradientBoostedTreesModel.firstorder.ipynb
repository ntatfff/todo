# %%
# Import packages and modules
import numpy  as np
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow_decision_forests as tfdf

from sklearn.model_selection import train_test_split
# Out:
# 2026-09-11 08:10:13.842426: I tensorflow/core/util/port.cc:113] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2026-09-11 08:10:13.895075: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2026-09-11 08:10:20.156674: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
# Check the version of TensorFlow Decision Forests
print("Found TensorFlow Decision Forests v" + tfdf.__version__)
# Out:
# Found TensorFlow Decision Forests v1.9.1

# %%
datasetPath = "dataset/10p/all/kernel3/"

# %%
# Parameters
datasetPath = "dataset/10p/firstorder/kernel4/"

# %%
# train/validation/test = 70/10/20
train_data = pd.read_csv(f"{datasetPath}dataset.train.csv")
validation_data = pd.read_csv(f"{datasetPath}dataset.validation.csv")
test_data = pd.read_csv(f"{datasetPath}dataset.test.csv")

# %%
from sklearn.utils.class_weight import compute_class_weight

# tinh class weight tren tap train
classes = np.array([0, 1])
weights = compute_class_weight(class_weight="balanced", classes=classes, y=train_data["label"])
class_weight = {0: weights[0], 1: weights[1]}

# gan sample_weight cho tung dong
train_data["sample_weight"] = train_data["label"].map(class_weight)
validation_data["sample_weight"] = validation_data["label"].map(class_weight)
test_data["sample_weight"] = test_data["label"].map(class_weight)

# Convert the dataset into a TensorFlow dataset.
train_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    train_data, label="label", weight="sample_weight"
)         
val_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    validation_data, label="label", weight="sample_weight"
)
test_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    test_data, label="label", weight="sample_weight"
)
# Out:
# 2026-09-11 08:10:34.859450: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:984] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2026-09-11 08:10:34.861091: W tensorflow/core/common_runtime/gpu/gpu_device.cc:2251] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...

# %%
import keras

# %%
# %%time

# Train a Gradient Boosted Trees model.
model = tfdf.keras.GradientBoostedTreesModel()

# Add evaluation metrics
model.compile(
    metrics=["accuracy"]
)
model.fit(x=train_ds)

# # Train a Gradient Boosted Trees model.
# model = tfdf.keras.GradientBoostedTreesModel(num_trees=1500)
# model.fit(train_ds)
# Out:
# Use /tmp/tmp63ent5mx as temporary training directory
# Reading training dataset...
# [WARNING 26-09-11 08:10:35.0126 UTC gradient_boosted_trees.cc:1840] "goss_alpha" set but "sampling_method" not equal to "GOSS".
# [WARNING 26-09-11 08:10:35.0127 UTC gradient_boosted_trees.cc:1851] "goss_beta" set but "sampling_method" not equal to "GOSS".
# [WARNING 26-09-11 08:10:35.0127 UTC gradient_boosted_trees.cc:1865] "selective_gradient_boosting_ratio" set but "sampling_method" not equal to "SELGB".
# Training dataset read in 0:00:03.145328. Found 13938 examples.
# Training model...
# Model trained in 0:00:01.240560
# Compiling model...
# [INFO 26-09-11 08:10:39.4234 UTC kernel.cc:1233] Loading model from path /tmp/tmp63ent5mx/model/ with prefix 71f5264733c341fe
# [INFO 26-09-11 08:10:39.4263 UTC quick_scorer_extended.cc:911] The binary was compiled without AVX2 support, but your CPU supports it. Enable it for faster model inference.
# [INFO 26-09-11 08:10:39.4265 UTC abstract_model.cc:1362] Engine "GradientBoostedTreesQuickScorerExtended" built
# [INFO 26-09-11 08:10:39.4265 UTC kernel.cc:1061] Use fast generic engine
# Model compiled.
# CPU times: user 13 s, sys: 716 ms, total: 13.7 s
# Wall time: 8.26 s

# %%
# Evaluate the model
evaluate = model.evaluate(val_ds, return_dict=True)
print()

for name, value in evaluate.items():
    print(f"{name}: {value:.4f}")
# Out:
# WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 1/2 [==============>...............] - ETA: 3s - loss: 0.0000e+00 - accuracy: 0.9460
# 2/2 [==============================] - 4s 12ms/step - loss: 0.0000e+00 - accuracy: 0.9492
# loss: 0.0000
# accuracy: 0.9492

# %%
# Model Summary
model.summary()
# Out:
# Model: "gradient_boosted_trees_model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
# =================================================================
# Total params: 1 (1.00 Byte)
# Trainable params: 0 (0.00 Byte)
# Non-trainable params: 1 (1.00 Byte)
# _________________________________________________________________
# Type: "GRADIENT_BOOSTED_TREES"
# Task: CLASSIFICATION
# Label: "__LABEL"
#
# Input Features (18):
# 	10Percentile
# 	90Percentile
# 	Energy
# 	Entropy
# 	InterquartileRange
# 	Kurtosis
# 	Maximum
# 	Mean
# 	MeanAbsoluteDeviation
# 	Median
# 	Minimum
# 	Range
# 	RobustMeanAbsoluteDeviation
# 	RootMeanSquared
# 	Skewness
# 	TotalEnergy
# 	Uniformity
# 	Variance
#
# Trained with weights
#
# Variable Importance: INV_MEAN_MIN_DEPTH:
#     1.                "90Percentile"  0.268886 ################
#     2.                      "Median"  0.239991 ###########
#     3.                     "Maximum"  0.217325 #######
#     4.                        "Mean"  0.216617 #######
#     5.                    "Skewness"  0.210647 ######
#     6.                  "Uniformity"  0.209941 ######
#     7.                "10Percentile"  0.207093 #####
#     8.                     "Minimum"  0.188870 ##
#     9.                    "Kurtosis"  0.184596 #
#    10.             "RootMeanSquared"  0.183165 #
#    11.                       "Range"  0.182583 #
#    12.                      "Energy"  0.181495 #
#    13.                 "TotalEnergy"  0.181051 #
#    14.          "InterquartileRange"  0.178732
#    15.                     "Entropy"  0.176100
#    16. "RobustMeanAbsoluteDeviation"  0.173576
#    17.       "MeanAbsoluteDeviation"  0.173332
#    18.                    "Variance"  0.172990
#
# Variable Importance: NUM_AS_ROOT:
#     1.    "90Percentile" 19.000000 ################
#     2.            "Mean" 10.000000 #######
#     3.          "Median"  9.000000 ######
#     4.          "Energy"  3.000000
#     5.         "Maximum"  3.000000
#     6. "RootMeanSquared"  3.000000
#     7.        "Skewness"  3.000000
#     8.     "TotalEnergy"  3.000000
#     9.    "10Percentile"  2.000000
#    10.         "Minimum"  2.000000
#    11.      "Uniformity"  2.000000
#
# Variable Importance: NUM_NODES:
#     1.                      "Median" 183.000000 ################
#     2.                    "Skewness" 177.000000 ###############
#     3.                     "Maximum" 176.000000 ###############
#     4.                  "Uniformity" 158.000000 #############
#     5.                "90Percentile" 139.000000 ###########
#     6.                "10Percentile" 120.000000 #########
#     7.                       "Range" 81.000000 #####
#     8.                    "Kurtosis" 80.000000 #####
#     9.                        "Mean" 76.000000 #####
#    10.                     "Minimum" 72.000000 ####
#    11.          "InterquartileRange" 47.000000 ##
#    12.                     "Entropy" 36.000000 #
#    13. "RobustMeanAbsoluteDeviation" 36.000000 #
#    14.             "RootMeanSquared" 33.000000 #
#    15.                      "Energy" 29.000000
#    16.                 "TotalEnergy" 26.000000
#    17.                    "Variance" 24.000000
#    18.       "MeanAbsoluteDeviation" 22.000000
#
# Variable Importance: SUM_SCORE:
#     1.                "90Percentile" 5084.384998 ################
#     2.                        "Mean" 1848.889661 #####
#     3.                      "Energy" 1592.435069 ####
#     4.                  "Uniformity" 822.326628 ##
#     5.                      "Median" 745.326314 ##
#     6.                     "Maximum" 736.130745 ##
#     7.                "10Percentile" 689.638098 ##
#     8.                 "TotalEnergy" 610.598653 #
#     9.                    "Skewness" 524.879743 #
#    10.             "RootMeanSquared" 405.981289 #
#    11.                    "Kurtosis" 249.067147
#    12.          "InterquartileRange" 197.144949
#    13.                     "Minimum" 189.948482
#    14.                       "Range" 140.186563
#    15.                     "Entropy" 137.765146
#    16. "RobustMeanAbsoluteDeviation" 101.711746
#    17.                    "Variance" 69.512958
#    18.       "MeanAbsoluteDeviation" 52.301173
#
#
#
# Loss: BINOMIAL_LOG_LIKELIHOOD
# Validation loss value: 0.527516
# Number of trees per iteration: 1
# Node format: NOT_SET
# Number of trees: 59
# Total number of nodes: 3089
#
# Number of nodes by tree:
# Count: 59 Average: 52.3559 StdDev: 7.50539
# Min: 37 Max: 63 Ignored: 0
# ----------------------------------------------
# [ 37, 38)  1   1.69%   1.69% #
# [ 38, 39)  0   0.00%   1.69%
# [ 39, 41)  2   3.39%   5.08% ##
# [ 41, 42)  6  10.17%  15.25% #####
# [ 42, 43)  0   0.00%  15.25%
# [ 43, 45)  6  10.17%  25.42% #####
# [ 45, 46)  1   1.69%  27.12% #
# [ 46, 47)  0   0.00%  27.12%
# [ 47, 49)  1   1.69%  28.81% #
# [ 49, 50)  2   3.39%  32.20% ##
# [ 50, 51)  0   0.00%  32.20%
# [ 51, 53)  5   8.47%  40.68% #####
# [ 53, 54)  5   8.47%  49.15% #####
# [ 54, 55)  0   0.00%  49.15%
# [ 55, 57)  3   5.08%  54.24% ###
# [ 57, 58)  8  13.56%  67.80% #######
# [ 58, 59)  0   0.00%  67.80%
# [ 59, 61) 11  18.64%  86.44% ##########
# [ 61, 62)  7  11.86%  98.31% ######
# [ 62, 63]  1   1.69% 100.00% #
#
# Depth by leafs:
# Count: 1574 Average: 4.85642 StdDev: 0.465827
# Min: 2 Max: 5 Ignored: 0
# ----------------------------------------------
# [ 2, 3)   14   0.89%   0.89%
# [ 3, 4)   32   2.03%   2.92%
# [ 4, 5)  120   7.62%  10.55% #
# [ 5, 5] 1408  89.45% 100.00% ##########
#
# Number of training obs by leaf:
# Count: 1574 Average: 470.088 StdDev: 1146.8
# Min: 5 Max: 10969 Ignored: 0
# ----------------------------------------------
# [     5,   553) 1308  83.10%  83.10% ##########
# [   553,  1101)   84   5.34%  88.44% #
# [  1101,  1649)   38   2.41%  90.85%
# [  1649,  2198)   40   2.54%  93.39%
# [  2198,  2746)   25   1.59%  94.98%
# [  2746,  3294)   19   1.21%  96.19%
# [  3294,  3842)   12   0.76%  96.95%
# [  3842,  4391)   10   0.64%  97.59%
# [  4391,  4939)    6   0.38%  97.97%
# [  4939,  5487)   10   0.64%  98.60%
# [  5487,  6035)    4   0.25%  98.86%
# [  6035,  6584)    7   0.44%  99.30%
# [  6584,  7132)    6   0.38%  99.68%
# [  7132,  7680)    2   0.13%  99.81%
# [  7680,  8228)    1   0.06%  99.87%
# [  8228,  8777)    1   0.06%  99.94%
# [  8777,  9325)    0   0.00%  99.94%
# [  9325,  9873)    0   0.00%  99.94%
# [  9873, 10421)    0   0.00%  99.94%
# [ 10421, 10969]    1   0.06% 100.00%
#
# Attribute in nodes:
# 	183 : Median [NUMERICAL]
# 	177 : Skewness [NUMERICAL]
# 	176 : Maximum [NUMERICAL]
# 	158 : Uniformity [NUMERICAL]
# 	139 : 90Percentile [NUMERICAL]
# 	120 : 10Percentile [NUMERICAL]
# 	81 : Range [NUMERICAL]
# 	80 : Kurtosis [NUMERICAL]
# 	76 : Mean [NUMERICAL]
# 	72 : Minimum [NUMERICAL]
# 	47 : InterquartileRange [NUMERICAL]
# 	36 : RobustMeanAbsoluteDeviation [NUMERICAL]
# 	36 : Entropy [NUMERICAL]
# 	33 : RootMeanSquared [NUMERICAL]
# 	29 : Energy [NUMERICAL]
# 	26 : TotalEnergy [NUMERICAL]
# 	24 : Variance [NUMERICAL]
# 	22 : MeanAbsoluteDeviation [NUMERICAL]
#
# Attribute in nodes with depth <= 0:
# 	19 : 90Percentile [NUMERICAL]
# 	10 : Mean [NUMERICAL]
# 	9 : Median [NUMERICAL]
# 	3 : TotalEnergy [NUMERICAL]
# 	3 : Skewness [NUMERICAL]
# 	3 : RootMeanSquared [NUMERICAL]
# 	3 : Maximum [NUMERICAL]
# 	3 : Energy [NUMERICAL]
# 	2 : Uniformity [NUMERICAL]
# 	2 : Minimum [NUMERICAL]
# 	2 : 10Percentile [NUMERICAL]
#
# Attribute in nodes with depth <= 1:
# 	28 : 90Percentile [NUMERICAL]
# 	25 : Median [NUMERICAL]
# 	25 : Mean [NUMERICAL]
# 	20 : 10Percentile [NUMERICAL]
# 	17 : Skewness [NUMERICAL]
# 	17 : Maximum [NUMERICAL]
# 	16 : Uniformity [NUMERICAL]
# 	8 : Minimum [NUMERICAL]
# 	5 : Range [NUMERICAL]
# 	4 : RootMeanSquared [NUMERICAL]
# 	3 : TotalEnergy [NUMERICAL]
# 	3 : Kurtosis [NUMERICAL]
# 	3 : Energy [NUMERICAL]
# 	2 : InterquartileRange [NUMERICAL]
# 	1 : MeanAbsoluteDeviation [NUMERICAL]
#
# Attribute in nodes with depth <= 2:
# 	52 : Maximum [NUMERICAL]
# 	51 : 90Percentile [NUMERICAL]
# 	50 : Median [NUMERICAL]
# 	46 : Uniformity [NUMERICAL]
# 	44 : Skewness [NUMERICAL]
# 	36 : Mean [NUMERICAL]
# 	28 : 10Percentile [NUMERICAL]
# 	21 : Minimum [NUMERICAL]
# 	16 : Kurtosis [NUMERICAL]
# 	13 : Range [NUMERICAL]
# 	9 : Entropy [NUMERICAL]
# 	9 : Energy [NUMERICAL]
# 	8 : RootMeanSquared [NUMERICAL]
# 	8 : InterquartileRange [NUMERICAL]
# 	5 : TotalEnergy [NUMERICAL]
# 	1 : Variance [NUMERICAL]
# 	1 : RobustMeanAbsoluteDeviation [NUMERICAL]
# 	1 : MeanAbsoluteDeviation [NUMERICAL]
#
# Attribute in nodes with depth <= 3:
# 	108 : Median [NUMERICAL]
# 	92 : Maximum [NUMERICAL]
# 	91 : Skewness [NUMERICAL]
# 	90 : Uniformity [NUMERICAL]
# 	90 : 90Percentile [NUMERICAL]
# 	67 : 10Percentile [NUMERICAL]
# 	52 : Mean [NUMERICAL]
# 	38 : Kurtosis [NUMERICAL]
# 	37 : Minimum [NUMERICAL]
# 	31 : Range [NUMERICAL]
# 	20 : InterquartileRange [NUMERICAL]
# 	19 : Entropy [NUMERICAL]
# 	18 : RootMeanSquared [NUMERICAL]
# 	18 : Energy [NUMERICAL]
# 	16 : TotalEnergy [NUMERICAL]
# 	9 : Variance [NUMERICAL]
# 	8 : RobustMeanAbsoluteDeviation [NUMERICAL]
# 	7 : MeanAbsoluteDeviation [NUMERICAL]
#
# Attribute in nodes with depth <= 5:
# 	183 : Median [NUMERICAL]
# 	177 : Skewness [NUMERICAL]
# 	176 : Maximum [NUMERICAL]
# 	158 : Uniformity [NUMERICAL]
# 	139 : 90Percentile [NUMERICAL]
# 	120 : 10Percentile [NUMERICAL]
# 	81 : Range [NUMERICAL]
# 	80 : Kurtosis [NUMERICAL]
# 	76 : Mean [NUMERICAL]
# 	72 : Minimum [NUMERICAL]
# 	47 : InterquartileRange [NUMERICAL]
# 	36 : RobustMeanAbsoluteDeviation [NUMERICAL]
# 	36 : Entropy [NUMERICAL]
# 	33 : RootMeanSquared [NUMERICAL]
# 	29 : Energy [NUMERICAL]
# 	26 : TotalEnergy [NUMERICAL]
# 	24 : Variance [NUMERICAL]
# 	22 : MeanAbsoluteDeviation [NUMERICAL]
#
# Condition type in nodes:
# 	1515 : HigherCondition
# Condition type in nodes with depth <= 0:
# 	59 : HigherCondition
# Condition type in nodes with depth <= 1:
# 	177 : HigherCondition
# Condition type in nodes with depth <= 2:
# 	399 : HigherCondition
# Condition type in nodes with depth <= 3:
# 	811 : HigherCondition
# Condition type in nodes with depth <= 5:
# 	1515 : HigherCondition
#
# Training logs:
# Number of iteration to final model: 59
# 	Iter:1 train-loss:1.262328 valid-loss:1.273898  train-accuracy:0.885427 valid-accuracy:0.837928
# 	Iter:2 train-loss:1.158942 valid-loss:1.175311  train-accuracy:0.888338 valid-accuracy:0.857638
# 	Iter:3 train-loss:1.072217 valid-loss:1.093086  train-accuracy:0.892785 valid-accuracy:0.875949
# 	Iter:4 train-loss:1.000084 valid-loss:1.028499  train-accuracy:0.892870 valid-accuracy:0.869890
# 	Iter:5 train-loss:0.931197 valid-loss:0.965642  train-accuracy:0.892664 valid-accuracy:0.864163
# 	Iter:6 train-loss:0.876771 valid-loss:0.919336  train-accuracy:0.904944 valid-accuracy:0.875084
# 	Iter:16 train-loss:0.567580 valid-loss:0.651064  train-accuracy:0.916912 valid-accuracy:0.864163
# 	Iter:26 train-loss:0.452833 valid-loss:0.574431  train-accuracy:0.924723 valid-accuracy:0.877481
# 	Iter:36 train-loss:0.388525 valid-loss:0.544691  train-accuracy:0.935104 valid-accuracy:0.878280
# 	Iter:46 train-loss:0.348328 valid-loss:0.534218  train-accuracy:0.943340 valid-accuracy:0.873419
# 	Iter:56 train-loss:0.317625 valid-loss:0.530922  train-accuracy:0.951229 valid-accuracy:0.871355
# 	Iter:66 train-loss:0.294814 valid-loss:0.533342  train-accuracy:0.957794 valid-accuracy:0.860035
# 	Iter:76 train-loss:0.275946 valid-loss:0.538580  train-accuracy:0.961986 valid-accuracy:0.861234
# 	Iter:86 train-loss:0.255726 valid-loss:0.547479  train-accuracy:0.968204 valid-accuracy:0.864030

# %%
# Model features
model.make_inspector().features()
# Out:
# ["10Percentile" (1; #0),
#  "90Percentile" (1; #1),
#  "Energy" (1; #2),
#  "Entropy" (1; #3),
#  "InterquartileRange" (1; #4),
#  "Kurtosis" (1; #5),
#  "Maximum" (1; #6),
#  "Mean" (1; #7),
#  "MeanAbsoluteDeviation" (1; #8),
#  "Median" (1; #9),
#  "Minimum" (1; #10),
#  "Range" (1; #11),
#  "RobustMeanAbsoluteDeviation" (1; #12),
#  "RootMeanSquared" (1; #13),
#  "Skewness" (1; #14),
#  "TotalEnergy" (1; #15),
#  "Uniformity" (1; #16),
#  "Variance" (1; #17)]

# %%
# Feature importance
model.make_inspector().variable_importances()
# Out:
# {'INV_MEAN_MIN_DEPTH': [("90Percentile" (1; #1), 0.2688860781001169),
#   ("Median" (1; #9), 0.2399912894623366),
#   ("Maximum" (1; #6), 0.21732457719496),
#   ("Mean" (1; #7), 0.2166170441668356),
#   ("Skewness" (1; #14), 0.21064691074881395),
#   ("Uniformity" (1; #16), 0.20994080201820456),
#   ("10Percentile" (1; #0), 0.20709265492865828),
#   ("Minimum" (1; #10), 0.1888702256521339),
#   ("Kurtosis" (1; #5), 0.18459578146847105),
#   ("RootMeanSquared" (1; #13), 0.18316474002312516),
#   ("Range" (1; #11), 0.18258255059973244),
#   ("Energy" (1; #2), 0.18149492191529368),
#   ("TotalEnergy" (1; #15), 0.18105064712096838),
#   ("InterquartileRange" (1; #4), 0.17873190480962978),
#   ("Entropy" (1; #3), 0.17610024758036047),
#   ("RobustMeanAbsoluteDeviation" (1; #12), 0.17357606160266587),
#   ("MeanAbsoluteDeviation" (1; #8), 0.17333171235322273),
#   ("Variance" (1; #17), 0.17298951925124484)],
#  'NUM_AS_ROOT': [("90Percentile" (1; #1), 19.0),
#   ("Mean" (1; #7), 10.0),
#   ("Median" (1; #9), 9.0),
#   ("Energy" (1; #2), 3.0),
#   ("Maximum" (1; #6), 3.0),
#   ("RootMeanSquared" (1; #13), 3.0),
#   ("Skewness" (1; #14), 3.0),
#   ("TotalEnergy" (1; #15), 3.0),
#   ("10Percentile" (1; #0), 2.0),
#   ("Minimum" (1; #10), 2.0),
#   ("Uniformity" (1; #16), 2.0)],
#  'SUM_SCORE': [("90Percentile" (1; #1), 5084.384998376751),
#   ("Mean" (1; #7), 1848.8896610117174),
#   ("Energy" (1; #2), 1592.435069249759),
#   ("Uniformity" (1; #16), 822.3266282015243),
#   ("Median" (1; #9), 745.3263139596512),
#   ("Maximum" (1; #6), 736.1307450178458),
#   ("10Percentile" (1; #0), 689.6380982217937),
#   ("TotalEnergy" (1; #15), 610.5986525412044),
#   ("Skewness" (1; #14), 524.8797428370555),
#   ("RootMeanSquared" (1; #13), 405.9812890541567),
#   ("Kurtosis" (1; #5), 249.06714710539606),
#   ("InterquartileRange" (1; #4), 197.14494850430648),
#   ("Minimum" (1; #10), 189.9484822270106),
#   ("Range" (1; #11), 140.18656290230444),
#   ("Entropy" (1; #3), 137.7651463226363),
#   ("RobustMeanAbsoluteDeviation" (1; #12), 101.71174550510287),
#   ("Variance" (1; #17), 69.512958413791),
#   ("MeanAbsoluteDeviation" (1; #8), 52.301172695701986)],
#  'NUM_NODES': [("Median" (1; #9), 183.0),
#   ("Skewness" (1; #14), 177.0),
#   ("Maximum" (1; #6), 176.0),
#   ("Uniformity" (1; #16), 158.0),
#   ("90Percentile" (1; #1), 139.0),
#   ("10Percentile" (1; #0), 120.0),
#   ("Range" (1; #11), 81.0),
#   ("Kurtosis" (1; #5), 80.0),
#   ("Mean" (1; #7), 76.0),
#   ("Minimum" (1; #10), 72.0),
#   ("InterquartileRange" (1; #4), 47.0),
#   ("Entropy" (1; #3), 36.0),
#   ("RobustMeanAbsoluteDeviation" (1; #12), 36.0),
#   ("RootMeanSquared" (1; #13), 33.0),
#   ("Energy" (1; #2), 29.0),
#   ("TotalEnergy" (1; #15), 26.0),
#   ("Variance" (1; #17), 24.0),
#   ("MeanAbsoluteDeviation" (1; #8), 22.0)]}

# %%
# Model self evaluation
model.make_inspector().evaluation()
# Out:
# Evaluation(num_examples=None, accuracy=0.8644964694976807, loss=0.527515709400177, rmse=None, ndcg=None, aucs=None, auuc=None, qini=None)

# %%
logs = model.make_inspector().training_logs()

plt.figure(figsize=(12, 4))
plt.subplot(1, 2, 1)
plt.plot([log.num_trees for log in logs], [log.evaluation.accuracy for log in logs])
plt.xlabel("Number of trees")
plt.ylabel("Accuracy (out-of-bag)")
plt.subplot(1, 2, 2)
plt.plot([log.num_trees for log in logs], [log.evaluation.loss for log in logs])
plt.xlabel("Number of trees")
plt.ylabel("Logloss (out-of-bag)")
plt.show()

# %% [markdown]
# Calculate the score of our hold-out validation dataset

# %%
predictions = model.predict(val_ds)
y_true      = validation_data["label"]

from sklearn.metrics import roc_auc_score
ROC_AUC = roc_auc_score(y_true, predictions)
print("The ROC AUC score is %.5f" % ROC_AUC )
# Out:
# 1/2 [==============>...............] - ETA: 0s
# 2/2 [==============================] - 1s 6ms/step
# The ROC AUC score is 0.99451

# %%
# Compute binary classification metrics with sklearn
import numpy as np
from sklearn.metrics import (
    accuracy_score,
    precision_score,
    recall_score,
    f1_score,
    roc_auc_score,
    average_precision_score,
    confusion_matrix,
    classification_report,
    matthews_corrcoef,
    log_loss,
    brier_score_loss,
)

# Get predictions (probabilities or class labels)
preds = model.predict(test_ds)
# If model outputs probabilities, convert to labels by threshold 0.5
if preds.ndim == 2:
    # For TFDF classification, preds may be class probabilities with shape (N, 2)
    if preds.shape[1] == 2:
        pos_probs = preds[:, 1]
    else:
        # If single-probability column (positive class)
        pos_probs = preds[:, -1]
    y_pred = (pos_probs >= 0.5).astype(int)
else:
    # Already class labels
    y_pred = preds.astype(int)
    pos_probs = None

# Ground truth labels (must be 0/1 integers)
y_true = test_data["label"].astype(int).to_numpy()

# Core metrics
metrics = {}
metrics["accuracy"] = accuracy_score(y_true, y_pred)
metrics["precision"] = precision_score(y_true, y_pred, zero_division=0)
metrics["recall"] = recall_score(y_true, y_pred, zero_division=0)
metrics["f1"] = f1_score(y_true, y_pred, zero_division=0)
metrics["mcc"] = matthews_corrcoef(y_true, y_pred)

# Probabilistic metrics (only if we have probabilities)
if pos_probs is not None:
    metrics["roc_auc"] = roc_auc_score(y_true, pos_probs)
    metrics["pr_auc"] = average_precision_score(y_true, pos_probs)
    metrics["log_loss"] = log_loss(y_true, pos_probs, labels=[0,1])
    metrics["brier_score"] = brier_score_loss(y_true, pos_probs)

# Confusion matrix and detailed report
cm = confusion_matrix(y_true, y_pred, labels=[0,1])
report = classification_report(y_true, y_pred, digits=4)

print("Sklearn binary metrics:")
for k, v in metrics.items():
    print(f"{k}: {v:.4f}")
print("\nConfusion matrix:\n", cm)
print("\nClassification report:\n", report)
# Out:
# 1/5 [=====>........................] - ETA: 0s
# 5/5 [==============================] - 0s 4ms/step
# Sklearn binary metrics:
# accuracy: 0.9560
# precision: 0.7354
# recall: 0.8610
# f1: 0.7933
# mcc: 0.7718
# roc_auc: 0.9552
# pr_auc: 0.8810
# log_loss: 0.1719
# brier_score: 0.0409
#
# Confusion matrix:
#  [[3642  127]
#  [  57  353]]
#
# Classification report:
#                precision    recall  f1-score   support
#
#            0     0.9846    0.9663    0.9754      3769
#            1     0.7354    0.8610    0.7933       410
#
#     accuracy                         0.9560      4179
#    macro avg     0.8600    0.9136    0.8843      4179
# weighted avg     0.9601    0.9560    0.9575      4179
