# %%
# Import packages and modules
import numpy  as np
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow_decision_forests as tfdf

from sklearn.model_selection import train_test_split
# Out:
# 2026-09-11 08:19:14.924450: I tensorflow/core/util/port.cc:113] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2026-09-11 08:19:14.965655: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2026-09-11 08:19:19.268615: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
# Check the version of TensorFlow Decision Forests
print("Found TensorFlow Decision Forests v" + tfdf.__version__)
# Out:
# Found TensorFlow Decision Forests v1.9.1

# %%
datasetPath = "dataset/10p/all/kernel3/"

# %%
# Parameters
datasetPath = "dataset/10p/firstorder/kernel4/"

# %%
# train/validation/test = 70/10/20
train_data = pd.read_csv(f"{datasetPath}dataset.train.csv")
validation_data = pd.read_csv(f"{datasetPath}dataset.validation.csv")
test_data = pd.read_csv(f"{datasetPath}dataset.test.csv")

# %%
from sklearn.utils.class_weight import compute_class_weight

# tinh class weight tren tap train
classes = np.array([0, 1])
weights = compute_class_weight(class_weight="balanced", classes=classes, y=train_data["label"])
class_weight = {0: weights[0], 1: weights[1]}

# gan sample_weight cho tung dong
train_data["sample_weight"] = train_data["label"].map(class_weight)
validation_data["sample_weight"] = validation_data["label"].map(class_weight)
test_data["sample_weight"] = test_data["label"].map(class_weight)

# Convert the dataset into a TensorFlow dataset.
train_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    train_data, label="label", weight="sample_weight"
)         
val_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    validation_data, label="label", weight="sample_weight"
)
test_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    test_data, label="label", weight="sample_weight"
)
# Out:
# 2026-09-11 08:19:31.207972: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:984] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2026-09-11 08:19:31.209351: W tensorflow/core/common_runtime/gpu/gpu_device.cc:2251] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...

# %%
import keras

# %%
# %%time

# Train a Random Forest model.
model = tfdf.keras.RandomForestModel()

# Add evaluation metrics
model.compile(
    metrics=["accuracy"]
)
model.fit(x=train_ds)

# # Train a Gradient Boosted Trees model.
# model = tfdf.keras.GradientBoostedTreesModel(num_trees=1500)
# model.fit(train_ds)
# Out:
# Use /tmp/tmp6ijebee_ as temporary training directory
# Reading training dataset...
# Training dataset read in 0:00:02.585410. Found 13938 examples.
# Training model...
# Model trained in 0:00:01.084013
# Compiling model...
# [INFO 26-09-11 08:19:34.8438 UTC kernel.cc:1233] Loading model from path /tmp/tmp6ijebee_/model/ with prefix 08b01261801749f7
# [INFO 26-09-11 08:19:34.9983 UTC decision_forest.cc:734] Model loaded with 300 root(s), 133402 node(s), and 18 input feature(s).
# [INFO 26-09-11 08:19:34.9983 UTC abstract_model.cc:1362] Engine "RandomForestOptPred" built
# [INFO 26-09-11 08:19:34.9983 UTC kernel.cc:1061] Use fast generic engine
# Model compiled.
# CPU times: user 15.2 s, sys: 117 ms, total: 15.3 s
# Wall time: 7.83 s

# %%
# Evaluate the model
evaluate = model.evaluate(val_ds, return_dict=True)
print()

for name, value in evaluate.items():
    print(f"{name}: {value:.4f}")
# Out:
# WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 1/2 [==============>...............] - ETA: 2s - loss: 0.0000e+00 - accuracy: 0.9860
# 2/2 [==============================] - 3s 22ms/step - loss: 0.0000e+00 - accuracy: 0.9846
# loss: 0.0000
# accuracy: 0.9846

# %%
# Model Summary
model.summary()
# Out:
# Model: "random_forest_model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
# =================================================================
# Total params: 1 (1.00 Byte)
# Trainable params: 0 (0.00 Byte)
# Non-trainable params: 1 (1.00 Byte)
# _________________________________________________________________
# Type: "RANDOM_FOREST"
# Task: CLASSIFICATION
# Label: "__LABEL"
#
# Input Features (18):
# 	10Percentile
# 	90Percentile
# 	Energy
# 	Entropy
# 	InterquartileRange
# 	Kurtosis
# 	Maximum
# 	Mean
# 	MeanAbsoluteDeviation
# 	Median
# 	Minimum
# 	Range
# 	RobustMeanAbsoluteDeviation
# 	RootMeanSquared
# 	Skewness
# 	TotalEnergy
# 	Uniformity
# 	Variance
#
# Trained with weights
#
# Variable Importance: INV_MEAN_MIN_DEPTH:
#     1.                "90Percentile"  0.167047 ################
#     2.                      "Median"  0.147383 ###########
#     3.                     "Maximum"  0.135470 ########
#     4.                 "TotalEnergy"  0.134364 ########
#     5.                      "Energy"  0.132274 #######
#     6.             "RootMeanSquared"  0.129165 #######
#     7.                        "Mean"  0.121334 #####
#     8.                "10Percentile"  0.120621 #####
#     9.                  "Uniformity"  0.115629 ####
#    10.          "InterquartileRange"  0.115584 ####
#    11.                    "Skewness"  0.112242 ###
#    12.                     "Entropy"  0.107489 ##
#    13. "RobustMeanAbsoluteDeviation"  0.105377 #
#    14.                     "Minimum"  0.103029 #
#    15.       "MeanAbsoluteDeviation"  0.100439
#    16.                    "Kurtosis"  0.100358
#    17.                    "Variance"  0.099807
#    18.                       "Range"  0.098424
#
# Variable Importance: NUM_AS_ROOT:
#     1.    "90Percentile" 81.000000 ################
#     2.     "TotalEnergy" 60.000000 ###########
#     3.          "Energy" 58.000000 ###########
#     4. "RootMeanSquared" 53.000000 ##########
#     5.            "Mean" 22.000000 ###
#     6.         "Maximum" 11.000000 #
#     7.          "Median"  9.000000 #
#     8.    "10Percentile"  3.000000
#     9.         "Minimum"  3.000000
#
# Variable Importance: NUM_NODES:
#     1.                     "Maximum" 5384.000000 ################
#     2.                    "Skewness" 5033.000000 #############
#     3.                  "Uniformity" 4361.000000 ##########
#     4.                      "Median" 4346.000000 #########
#     5.                    "Kurtosis" 4248.000000 #########
#     6.                "90Percentile" 4105.000000 ########
#     7.                       "Range" 3766.000000 ######
#     8.                     "Entropy" 3663.000000 ######
#     9.          "InterquartileRange" 3642.000000 #####
#    10.                "10Percentile" 3544.000000 #####
#    11.                     "Minimum" 3534.000000 #####
#    12. "RobustMeanAbsoluteDeviation" 3476.000000 ####
#    13.                    "Variance" 3246.000000 ###
#    14.       "MeanAbsoluteDeviation" 3049.000000 ##
#    15.                        "Mean" 3038.000000 ##
#    16.                 "TotalEnergy" 2762.000000
#    17.                      "Energy" 2734.000000
#    18.             "RootMeanSquared" 2620.000000
#
# Variable Importance: SUM_SCORE:
#     1.                "90Percentile" 436541.421563 ################
#     2.                 "TotalEnergy" 316861.648975 ##########
#     3.                      "Energy" 305507.577905 ##########
#     4.             "RootMeanSquared" 276934.018548 #########
#     5.                     "Maximum" 184413.549019 #####
#     6.                      "Median" 179957.743925 #####
#     7.                        "Mean" 168905.009675 ####
#     8.                  "Uniformity" 100727.776593 #
#     9.                "10Percentile" 99567.761905 #
#    10.                    "Skewness" 98418.252014 #
#    11.          "InterquartileRange" 83145.002625 #
#    12.                     "Entropy" 70833.602546
#    13. "RobustMeanAbsoluteDeviation" 68422.922324
#    14.                    "Kurtosis" 67879.736707
#    15.                     "Minimum" 66382.920620
#    16.                       "Range" 61582.737474
#    17.                    "Variance" 56952.783142
#    18.       "MeanAbsoluteDeviation" 56027.993906
#
#
#
# Winner takes all: true
# Out-of-bag evaluation: accuracy:0.842655 logloss:0.596951
# Number of trees: 300
# Total number of nodes: 133402
#
# Number of nodes by tree:
# Count: 300 Average: 444.673 StdDev: 22.9977
# Min: 367 Max: 493 Ignored: 0
# ----------------------------------------------
# [ 367, 373)  1   0.33%   0.33%
# [ 373, 379)  0   0.00%   0.33%
# [ 379, 386)  1   0.33%   0.67%
# [ 386, 392)  2   0.67%   1.33% #
# [ 392, 398)  9   3.00%   4.33% ##
# [ 398, 405) 10   3.33%   7.67% ###
# [ 405, 411)  4   1.33%   9.00% #
# [ 411, 417)  6   2.00%  11.00% ##
# [ 417, 424) 16   5.33%  16.33% ####
# [ 424, 430) 18   6.00%  22.33% #####
# [ 430, 436) 30  10.00%  32.33% ########
# [ 436, 443) 27   9.00%  41.33% #######
# [ 443, 449) 38  12.67%  54.00% ##########
# [ 449, 455) 35  11.67%  65.67% #########
# [ 455, 462) 32  10.67%  76.33% ########
# [ 462, 468) 30  10.00%  86.33% ########
# [ 468, 474) 12   4.00%  90.33% ###
# [ 474, 481) 11   3.67%  94.00% ###
# [ 481, 487) 11   3.67%  97.67% ###
# [ 487, 493]  7   2.33% 100.00% ##
#
# Depth by leafs:
# Count: 66851 Average: 10.5632 StdDev: 2.83637
# Min: 2 Max: 15 Ignored: 0
# ----------------------------------------------
# [  2,  3)   87   0.13%   0.13%
# [  3,  4)  355   0.53%   0.66%
# [  4,  5)  769   1.15%   1.81% #
# [  5,  6) 1651   2.47%   4.28% ##
# [  6,  7) 2911   4.35%   8.64% ####
# [  7,  8) 4537   6.79%  15.42% #####
# [  8,  9) 5977   8.94%  24.36% #######
# [  9, 10) 7440  11.13%  35.49% #########
# [ 10, 11) 8289  12.40%  47.89% ##########
# [ 11, 12) 8253  12.35%  60.24% ##########
# [ 12, 13) 7845  11.74%  71.97% #########
# [ 13, 14) 6890  10.31%  82.28% ########
# [ 14, 15) 5497   8.22%  90.50% #######
# [ 15, 15] 6350   9.50% 100.00% ########
#
# Number of training obs by leaf:
# Count: 66851 Average: 62.5481 StdDev: 214.271
# Min: 5 Max: 3064 Ignored: 0
# ----------------------------------------------
# [    5,  158) 61802  92.45%  92.45% ##########
# [  158,  311)  2052   3.07%  95.52%
# [  311,  464)  1069   1.60%  97.12%
# [  464,  617)   472   0.71%  97.82%
# [  617,  770)   310   0.46%  98.29%
# [  770,  923)   216   0.32%  98.61%
# [  923, 1076)   145   0.22%  98.83%
# [ 1076, 1229)   129   0.19%  99.02%
# [ 1229, 1382)    89   0.13%  99.15%
# [ 1382, 1535)    79   0.12%  99.27%
# [ 1535, 1688)   132   0.20%  99.47%
# [ 1688, 1841)    95   0.14%  99.61%
# [ 1841, 1994)    47   0.07%  99.68%
# [ 1994, 2147)    40   0.06%  99.74%
# [ 2147, 2300)   106   0.16%  99.90%
# [ 2300, 2453)    36   0.05%  99.95%
# [ 2453, 2606)    11   0.02%  99.97%
# [ 2606, 2759)    14   0.02%  99.99%
# [ 2759, 2912)     5   0.01% 100.00%
# [ 2912, 3064]     2   0.00% 100.00%
#
# Attribute in nodes:
# 	5384 : Maximum [NUMERICAL]
# 	5033 : Skewness [NUMERICAL]
# 	4361 : Uniformity [NUMERICAL]
# 	4346 : Median [NUMERICAL]
# 	4248 : Kurtosis [NUMERICAL]
# 	4105 : 90Percentile [NUMERICAL]
# 	3766 : Range [NUMERICAL]
# 	3663 : Entropy [NUMERICAL]
# 	3642 : InterquartileRange [NUMERICAL]
# 	3544 : 10Percentile [NUMERICAL]
# 	3534 : Minimum [NUMERICAL]
# 	3476 : RobustMeanAbsoluteDeviation [NUMERICAL]
# 	3246 : Variance [NUMERICAL]
# 	3049 : MeanAbsoluteDeviation [NUMERICAL]
# 	3038 : Mean [NUMERICAL]
# 	2762 : TotalEnergy [NUMERICAL]
# 	2734 : Energy [NUMERICAL]
# 	2620 : RootMeanSquared [NUMERICAL]
#
# Attribute in nodes with depth <= 0:
# 	81 : 90Percentile [NUMERICAL]
# 	60 : TotalEnergy [NUMERICAL]
# 	58 : Energy [NUMERICAL]
# 	53 : RootMeanSquared [NUMERICAL]
# 	22 : Mean [NUMERICAL]
# 	11 : Maximum [NUMERICAL]
# 	9 : Median [NUMERICAL]
# 	3 : Minimum [NUMERICAL]
# 	3 : 10Percentile [NUMERICAL]
#
# Attribute in nodes with depth <= 1:
# 	154 : TotalEnergy [NUMERICAL]
# 	149 : Energy [NUMERICAL]
# 	132 : Median [NUMERICAL]
# 	122 : RootMeanSquared [NUMERICAL]
# 	122 : 90Percentile [NUMERICAL]
# 	95 : Mean [NUMERICAL]
# 	77 : 10Percentile [NUMERICAL]
# 	21 : Maximum [NUMERICAL]
# 	19 : Minimum [NUMERICAL]
# 	4 : RobustMeanAbsoluteDeviation [NUMERICAL]
# 	4 : InterquartileRange [NUMERICAL]
# 	1 : Range [NUMERICAL]
#
# Attribute in nodes with depth <= 2:
# 	301 : Median [NUMERICAL]
# 	225 : Energy [NUMERICAL]
# 	217 : TotalEnergy [NUMERICAL]
# 	212 : 90Percentile [NUMERICAL]
# 	178 : RootMeanSquared [NUMERICAL]
# 	173 : Mean [NUMERICAL]
# 	132 : 10Percentile [NUMERICAL]
# 	87 : InterquartileRange [NUMERICAL]
# 	86 : Skewness [NUMERICAL]
# 	81 : Maximum [NUMERICAL]
# 	78 : Uniformity [NUMERICAL]
# 	62 : Minimum [NUMERICAL]
# 	54 : Entropy [NUMERICAL]
# 	47 : RobustMeanAbsoluteDeviation [NUMERICAL]
# 	28 : MeanAbsoluteDeviation [NUMERICAL]
# 	20 : Kurtosis [NUMERICAL]
# 	19 : Variance [NUMERICAL]
# 	13 : Range [NUMERICAL]
#
# Attribute in nodes with depth <= 3:
# 	459 : Median [NUMERICAL]
# 	369 : 90Percentile [NUMERICAL]
# 	319 : TotalEnergy [NUMERICAL]
# 	311 : Energy [NUMERICAL]
# 	293 : Skewness [NUMERICAL]
# 	291 : Maximum [NUMERICAL]
# 	287 : Mean [NUMERICAL]
# 	255 : RootMeanSquared [NUMERICAL]
# 	201 : Uniformity [NUMERICAL]
# 	194 : 10Percentile [NUMERICAL]
# 	176 : InterquartileRange [NUMERICAL]
# 	140 : Minimum [NUMERICAL]
# 	139 : Entropy [NUMERICAL]
# 	104 : RobustMeanAbsoluteDeviation [NUMERICAL]
# 	98 : Kurtosis [NUMERICAL]
# 	86 : MeanAbsoluteDeviation [NUMERICAL]
# 	82 : Range [NUMERICAL]
# 	80 : Variance [NUMERICAL]
#
# Attribute in nodes with depth <= 5:
# 	1131 : Maximum [NUMERICAL]
# 	1027 : Median [NUMERICAL]
# 	889 : 90Percentile [NUMERICAL]
# 	882 : Skewness [NUMERICAL]
# 	706 : Uniformity [NUMERICAL]
# 	623 : TotalEnergy [NUMERICAL]
# 	602 : Mean [NUMERICAL]
# 	592 : Energy [NUMERICAL]
# 	554 : RootMeanSquared [NUMERICAL]
# 	550 : InterquartileRange [NUMERICAL]
# 	542 : 10Percentile [NUMERICAL]
# 	527 : Entropy [NUMERICAL]
# 	511 : Kurtosis [NUMERICAL]
# 	445 : Minimum [NUMERICAL]
# 	436 : Range [NUMERICAL]
# 	435 : RobustMeanAbsoluteDeviation [NUMERICAL]
# 	362 : Variance [NUMERICAL]
# 	338 : MeanAbsoluteDeviation [NUMERICAL]
#
# Condition type in nodes:
# 	66551 : HigherCondition
# Condition type in nodes with depth <= 0:
# 	300 : HigherCondition
# Condition type in nodes with depth <= 1:
# 	900 : HigherCondition
# Condition type in nodes with depth <= 2:
# 	2013 : HigherCondition
# Condition type in nodes with depth <= 3:
# 	3884 : HigherCondition
# Condition type in nodes with depth <= 5:
# 	11152 : HigherCondition
# Node format: NOT_SET
#
# Training OOB:
# 	trees: 1, Out-of-bag evaluation: accuracy:0.83471 logloss:5.95765
# 	trees: 12, Out-of-bag evaluation: accuracy:0.819431 logloss:4.25444
# 	trees: 22, Out-of-bag evaluation: accuracy:0.836555 logloss:1.93007
# 	trees: 32, Out-of-bag evaluation: accuracy:0.837701 logloss:1.4967
# 	trees: 42, Out-of-bag evaluation: accuracy:0.84197 logloss:1.31082
# 	trees: 52, Out-of-bag evaluation: accuracy:0.840799 logloss:1.18611
# 	trees: 62, Out-of-bag evaluation: accuracy:0.842706 logloss:1.07525
# 	trees: 72, Out-of-bag evaluation: accuracy:0.841151 logloss:1.00185
# 	trees: 82, Out-of-bag evaluation: accuracy:0.841573 logloss:0.912283
# 	trees: 92, Out-of-bag evaluation: accuracy:0.842354 logloss:0.878468
# 	trees: 102, Out-of-bag evaluation: accuracy:0.841733 logloss:0.824759
# 	trees: 112, Out-of-bag evaluation: accuracy:0.844178 logloss:0.772605
# 	trees: 122, Out-of-bag evaluation: accuracy:0.844799 logloss:0.771394
# 	trees: 132, Out-of-bag evaluation: accuracy:0.844294 logloss:0.735182
# 	trees: 142, Out-of-bag evaluation: accuracy:0.843244 logloss:0.700388
# 	trees: 152, Out-of-bag evaluation: accuracy:0.843282 logloss:0.701025
# 	trees: 162, Out-of-bag evaluation: accuracy:0.843826 logloss:0.701264
# 	trees: 172, Out-of-bag evaluation: accuracy:0.84503 logloss:0.701601
# 	trees: 182, Out-of-bag evaluation: accuracy:0.842348 logloss:0.701344
# 	trees: 192, Out-of-bag evaluation: accuracy:0.841842 logloss:0.665451
# 	trees: 202, Out-of-bag evaluation: accuracy:0.842892 logloss:0.648571
# 	trees: 212, Out-of-bag evaluation: accuracy:0.842463 logloss:0.648314
# 	trees: 222, Out-of-bag evaluation: accuracy:0.842578 logloss:0.630265
# 	trees: 232, Out-of-bag evaluation: accuracy:0.843007 logloss:0.611577
# 	trees: 242, Out-of-bag evaluation: accuracy:0.842853 logloss:0.612225
# 	trees: 252, Out-of-bag evaluation: accuracy:0.843084 logloss:0.595476
# 	trees: 262, Out-of-bag evaluation: accuracy:0.843743 logloss:0.595617
# 	trees: 272, Out-of-bag evaluation: accuracy:0.843589 logloss:0.595866
# 	trees: 282, Out-of-bag evaluation: accuracy:0.842693 logloss:0.596055
# 	trees: 292, Out-of-bag evaluation: accuracy:0.842463 logloss:0.596203
# 	trees: 300, Out-of-bag evaluation: accuracy:0.842655 logloss:0.596951

# %%
# Model features
model.make_inspector().features()
# Out:
# ["10Percentile" (1; #0),
#  "90Percentile" (1; #1),
#  "Energy" (1; #2),
#  "Entropy" (1; #3),
#  "InterquartileRange" (1; #4),
#  "Kurtosis" (1; #5),
#  "Maximum" (1; #6),
#  "Mean" (1; #7),
#  "MeanAbsoluteDeviation" (1; #8),
#  "Median" (1; #9),
#  "Minimum" (1; #10),
#  "Range" (1; #11),
#  "RobustMeanAbsoluteDeviation" (1; #12),
#  "RootMeanSquared" (1; #13),
#  "Skewness" (1; #14),
#  "TotalEnergy" (1; #15),
#  "Uniformity" (1; #16),
#  "Variance" (1; #17)]

# %%
# Feature importance
model.make_inspector().variable_importances()
# Out:
# {'INV_MEAN_MIN_DEPTH': [("90Percentile" (1; #1), 0.16704712597602803),
#   ("Median" (1; #9), 0.14738282521341806),
#   ("Maximum" (1; #6), 0.13547001206483544),
#   ("TotalEnergy" (1; #15), 0.13436420984314823),
#   ("Energy" (1; #2), 0.13227442115302834),
#   ("RootMeanSquared" (1; #13), 0.129165459827457),
#   ("Mean" (1; #7), 0.12133357738664434),
#   ("10Percentile" (1; #0), 0.1206211840156899),
#   ("Uniformity" (1; #16), 0.11562932360025242),
#   ("InterquartileRange" (1; #4), 0.11558382489305295),
#   ("Skewness" (1; #14), 0.11224185352984821),
#   ("Entropy" (1; #3), 0.10748916961004047),
#   ("RobustMeanAbsoluteDeviation" (1; #12), 0.1053773653860832),
#   ("Minimum" (1; #10), 0.10302891405284169),
#   ("MeanAbsoluteDeviation" (1; #8), 0.10043873286873124),
#   ("Kurtosis" (1; #5), 0.10035766099668844),
#   ("Variance" (1; #17), 0.09980734335616388),
#   ("Range" (1; #11), 0.09842361813364997)],
#  'SUM_SCORE': [("90Percentile" (1; #1), 436541.42156291107),
#   ("TotalEnergy" (1; #15), 316861.6489754427),
#   ("Energy" (1; #2), 305507.5779052573),
#   ("RootMeanSquared" (1; #13), 276934.01854844997),
#   ("Maximum" (1; #6), 184413.5490186279),
#   ("Median" (1; #9), 179957.74392462164),
#   ("Mean" (1; #7), 168905.00967507603),
#   ("Uniformity" (1; #16), 100727.77659299629),
#   ("10Percentile" (1; #0), 99567.76190489747),
#   ("Skewness" (1; #14), 98418.25201371837),
#   ("InterquartileRange" (1; #4), 83145.00262493303),
#   ("Entropy" (1; #3), 70833.6025461738),
#   ("RobustMeanAbsoluteDeviation" (1; #12), 68422.92232428567),
#   ("Kurtosis" (1; #5), 67879.73670666234),
#   ("Minimum" (1; #10), 66382.92062049554),
#   ("Range" (1; #11), 61582.73747449947),
#   ("Variance" (1; #17), 56952.78314207588),
#   ("MeanAbsoluteDeviation" (1; #8), 56027.99390623104)],
#  'NUM_AS_ROOT': [("90Percentile" (1; #1), 81.0),
#   ("TotalEnergy" (1; #15), 60.0),
#   ("Energy" (1; #2), 58.0),
#   ("RootMeanSquared" (1; #13), 53.0),
#   ("Mean" (1; #7), 22.0),
#   ("Maximum" (1; #6), 11.0),
#   ("Median" (1; #9), 9.0),
#   ("10Percentile" (1; #0), 3.0),
#   ("Minimum" (1; #10), 3.0)],
#  'NUM_NODES': [("Maximum" (1; #6), 5384.0),
#   ("Skewness" (1; #14), 5033.0),
#   ("Uniformity" (1; #16), 4361.0),
#   ("Median" (1; #9), 4346.0),
#   ("Kurtosis" (1; #5), 4248.0),
#   ("90Percentile" (1; #1), 4105.0),
#   ("Range" (1; #11), 3766.0),
#   ("Entropy" (1; #3), 3663.0),
#   ("InterquartileRange" (1; #4), 3642.0),
#   ("10Percentile" (1; #0), 3544.0),
#   ("Minimum" (1; #10), 3534.0),
#   ("RobustMeanAbsoluteDeviation" (1; #12), 3476.0),
#   ("Variance" (1; #17), 3246.0),
#   ("MeanAbsoluteDeviation" (1; #8), 3049.0),
#   ("Mean" (1; #7), 3038.0),
#   ("TotalEnergy" (1; #15), 2762.0),
#   ("Energy" (1; #2), 2734.0),
#   ("RootMeanSquared" (1; #13), 2620.0)]}

# %%
# Model self evaluation
model.make_inspector().evaluation()
# Out:
# Evaluation(num_examples=13938, accuracy=0.8426549687225456, loss=0.5969509768073324, rmse=None, ndcg=None, aucs=None, auuc=None, qini=None)

# %%
logs = model.make_inspector().training_logs()

plt.figure(figsize=(12, 4))
plt.subplot(1, 2, 1)
plt.plot([log.num_trees for log in logs], [log.evaluation.accuracy for log in logs])
plt.xlabel("Number of trees")
plt.ylabel("Accuracy (out-of-bag)")
plt.subplot(1, 2, 2)
plt.plot([log.num_trees for log in logs], [log.evaluation.loss for log in logs])
plt.xlabel("Number of trees")
plt.ylabel("Logloss (out-of-bag)")
plt.show()

# %% [markdown]
# Calculate the score of our hold-out validation dataset

# %%
predictions = model.predict(val_ds)
y_true      = validation_data["label"]

from sklearn.metrics import roc_auc_score
ROC_AUC = roc_auc_score(y_true, predictions)
print("The ROC AUC score is %.5f" % ROC_AUC )
# Out:
# 1/2 [==============>...............] - ETA: 0s
# 2/2 [==============================] - 0s 16ms/step
# The ROC AUC score is 0.99665

# %%
# Compute binary classification metrics with sklearn
import numpy as np
from sklearn.metrics import (
    accuracy_score,
    precision_score,
    recall_score,
    f1_score,
    roc_auc_score,
    average_precision_score,
    confusion_matrix,
    classification_report,
    matthews_corrcoef,
    log_loss,
    brier_score_loss,
)

# Get predictions (probabilities or class labels)
preds = model.predict(test_ds)
# If model outputs probabilities, convert to labels by threshold 0.5
if preds.ndim == 2:
    # For TFDF classification, preds may be class probabilities with shape (N, 2)
    if preds.shape[1] == 2:
        pos_probs = preds[:, 1]
    else:
        # If single-probability column (positive class)
        pos_probs = preds[:, -1]
    y_pred = (pos_probs >= 0.5).astype(int)
else:
    # Already class labels
    y_pred = preds.astype(int)
    pos_probs = None

# Ground truth labels (must be 0/1 integers)
y_true = test_data["label"].astype(int).to_numpy()

# Core metrics
metrics = {}
metrics["accuracy"] = accuracy_score(y_true, y_pred)
metrics["precision"] = precision_score(y_true, y_pred, zero_division=0)
metrics["recall"] = recall_score(y_true, y_pred, zero_division=0)
metrics["f1"] = f1_score(y_true, y_pred, zero_division=0)
metrics["mcc"] = matthews_corrcoef(y_true, y_pred)

# Probabilistic metrics (only if we have probabilities)
if pos_probs is not None:
    metrics["roc_auc"] = roc_auc_score(y_true, pos_probs)
    metrics["pr_auc"] = average_precision_score(y_true, pos_probs)
    metrics["log_loss"] = log_loss(y_true, pos_probs, labels=[0,1])
    metrics["brier_score"] = brier_score_loss(y_true, pos_probs)

# Confusion matrix and detailed report
cm = confusion_matrix(y_true, y_pred, labels=[0,1])
report = classification_report(y_true, y_pred, digits=4)

print("Sklearn binary metrics:")
for k, v in metrics.items():
    print(f"{k}: {v:.4f}")
print("\nConfusion matrix:\n", cm)
print("\nClassification report:\n", report)
# Out:
# 1/5 [=====>........................] - ETA: 0s
# 5/5 [==============================] - ETA: 0s
# 5/5 [==============================] - 0s 13ms/step
# Sklearn binary metrics:
# accuracy: 0.9617
# precision: 0.8019
# recall: 0.8098
# f1: 0.8058
# mcc: 0.7846
# roc_auc: 0.9614
# pr_auc: 0.8654
# log_loss: 0.1307
# brier_score: 0.0299
#
# Confusion matrix:
#  [[3687   82]
#  [  78  332]]
#
# Classification report:
#                precision    recall  f1-score   support
#
#            0     0.9793    0.9782    0.9788      3769
#            1     0.8019    0.8098    0.8058       410
#
#     accuracy                         0.9617      4179
#    macro avg     0.8906    0.8940    0.8923      4179
# weighted avg     0.9619    0.9617    0.9618      4179
