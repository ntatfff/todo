# %%
# Import packages and modules
import numpy  as np
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow_decision_forests as tfdf

from sklearn.model_selection import train_test_split
# Out:
# 2026-09-11 08:10:56.625534: I tensorflow/core/util/port.cc:113] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2026-09-11 08:10:56.679113: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2026-09-11 08:11:01.989592: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
# Check the version of TensorFlow Decision Forests
print("Found TensorFlow Decision Forests v" + tfdf.__version__)
# Out:
# Found TensorFlow Decision Forests v1.9.1

# %%
datasetPath = "dataset/10p/all/kernel3/"

# %%
# Parameters
datasetPath = "dataset/10p/glcm/kernel4/"

# %%
# train/validation/test = 70/10/20
train_data = pd.read_csv(f"{datasetPath}dataset.train.csv")
validation_data = pd.read_csv(f"{datasetPath}dataset.validation.csv")
test_data = pd.read_csv(f"{datasetPath}dataset.test.csv")

# %%
from sklearn.utils.class_weight import compute_class_weight

# tinh class weight tren tap train
classes = np.array([0, 1])
weights = compute_class_weight(class_weight="balanced", classes=classes, y=train_data["label"])
class_weight = {0: weights[0], 1: weights[1]}

# gan sample_weight cho tung dong
train_data["sample_weight"] = train_data["label"].map(class_weight)
validation_data["sample_weight"] = validation_data["label"].map(class_weight)
test_data["sample_weight"] = test_data["label"].map(class_weight)

# Convert the dataset into a TensorFlow dataset.
train_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    train_data, label="label", weight="sample_weight"
)         
val_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    validation_data, label="label", weight="sample_weight"
)
test_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    test_data, label="label", weight="sample_weight"
)
# Out:
# 2026-09-11 08:11:16.754718: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:984] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2026-09-11 08:11:16.756229: W tensorflow/core/common_runtime/gpu/gpu_device.cc:2251] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...

# %%
import keras

# %%
# %%time

# Train a Gradient Boosted Trees model.
model = tfdf.keras.GradientBoostedTreesModel()

# Add evaluation metrics
model.compile(
    metrics=["accuracy"]
)
model.fit(x=train_ds)

# # Train a Gradient Boosted Trees model.
# model = tfdf.keras.GradientBoostedTreesModel(num_trees=1500)
# model.fit(train_ds)
# Out:
# Use /tmp/tmpcpy96_ny as temporary training directory
# Reading training dataset...
# [WARNING 26-09-11 08:11:16.9099 UTC gradient_boosted_trees.cc:1840] "goss_alpha" set but "sampling_method" not equal to "GOSS".
# [WARNING 26-09-11 08:11:16.9100 UTC gradient_boosted_trees.cc:1851] "goss_beta" set but "sampling_method" not equal to "GOSS".
# [WARNING 26-09-11 08:11:16.9100 UTC gradient_boosted_trees.cc:1865] "selective_gradient_boosting_ratio" set but "sampling_method" not equal to "SELGB".
# Training dataset read in 0:00:04.389132. Found 13938 examples.
# Training model...
# Model trained in 0:00:03.770183
# Compiling model...
# [INFO 26-09-11 08:11:25.0828 UTC kernel.cc:1233] Loading model from path /tmp/tmpcpy96_ny/model/ with prefix 86a693cf0c6c4cb0
# [INFO 26-09-11 08:11:25.0921 UTC quick_scorer_extended.cc:911] The binary was compiled without AVX2 support, but your CPU supports it. Enable it for faster model inference.
# [INFO 26-09-11 08:11:25.0929 UTC abstract_model.cc:1362] Engine "GradientBoostedTreesQuickScorerExtended" built
# [INFO 26-09-11 08:11:25.0929 UTC kernel.cc:1061] Use fast generic engine
# Model compiled.
# CPU times: user 29.6 s, sys: 1.77 s, total: 31.4 s
# Wall time: 12.1 s

# %%
# Evaluate the model
evaluate = model.evaluate(val_ds, return_dict=True)
print()

for name, value in evaluate.items():
    print(f"{name}: {value:.4f}")
# Out:
# WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 1/2 [==============>...............] - ETA: 3s - loss: 0.0000e+00 - accuracy: 0.9920
# 2/2 [==============================] - 4s 13ms/step - loss: 0.0000e+00 - accuracy: 0.9928
# loss: 0.0000
# accuracy: 0.9928

# %%
# Model Summary
model.summary()
# Out:
# Model: "gradient_boosted_trees_model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
# =================================================================
# Total params: 1 (1.00 Byte)
# Trainable params: 0 (0.00 Byte)
# Non-trainable params: 1 (1.00 Byte)
# _________________________________________________________________
# Type: "GRADIENT_BOOSTED_TREES"
# Task: CLASSIFICATION
# Label: "__LABEL"
#
# Input Features (24):
# 	Autocorrelation
# 	ClusterProminence
# 	ClusterShade
# 	ClusterTendency
# 	Contrast
# 	Correlation
# 	DifferenceAverage
# 	DifferenceEntropy
# 	DifferenceVariance
# 	Id
# 	Idm
# 	Idmn
# 	Idn
# 	Imc1
# 	Imc2
# 	InverseVariance
# 	JointAverage
# 	JointEnergy
# 	JointEntropy
# 	MCC
# 	MaximumProbability
# 	SumAverage
# 	SumEntropy
# 	SumSquares
#
# Trained with weights
#
# Variable Importance: INV_MEAN_MIN_DEPTH:
#     1.    "Autocorrelation"  0.255548 ################
#     2.                "Idn"  0.236007 ############
#     3.         "SumAverage"  0.220301 ########
#     4.       "JointAverage"  0.218275 ########
#     5.    "InverseVariance"  0.204276 #####
#     6.       "ClusterShade"  0.195388 ###
#     7.        "Correlation"  0.194432 ###
#     8.               "Imc1"  0.192521 ###
#     9.               "Idmn"  0.187373 ##
#    10.                 "Id"  0.186253 ##
#    11.  "DifferenceAverage"  0.183109 #
#    12. "DifferenceVariance"  0.182824 #
#    13. "MaximumProbability"  0.182766 #
#    14.  "DifferenceEntropy"  0.181583 #
#    15.                "Idm"  0.181127 #
#    16.           "Contrast"  0.180904 #
#    17.                "MCC"  0.180468 #
#    18.         "SumEntropy"  0.179934
#    19.               "Imc2"  0.178748
#    20.    "ClusterTendency"  0.178530
#    21.       "JointEntropy"  0.177088
#    22.  "ClusterProminence"  0.176715
#    23.        "JointEnergy"  0.175654
#    24.         "SumSquares"  0.175371
#
# Variable Importance: NUM_AS_ROOT:
#     1. "Autocorrelation" 54.000000 ################
#     2.      "SumAverage" 38.000000 ##########
#     3.    "JointAverage" 32.000000 ########
#     4.             "Idn" 25.000000 ######
#     5.     "Correlation" 14.000000 ##
#     6.            "Imc1" 14.000000 ##
#     7. "InverseVariance" 11.000000 #
#     8.            "Idmn"  7.000000
#     9.              "Id"  6.000000
#
# Variable Importance: NUM_NODES:
#     1.    "Autocorrelation" 545.000000 ################
#     2.                "Idn" 525.000000 ###############
#     3.       "ClusterShade" 370.000000 ##########
#     4.    "InverseVariance" 291.000000 #######
#     5.         "SumAverage" 286.000000 #######
#     6.       "JointAverage" 282.000000 #######
#     7.        "Correlation" 217.000000 #####
#     8.               "Idmn" 216.000000 #####
#     9. "MaximumProbability" 190.000000 ####
#    10.               "Imc1" 179.000000 ###
#    11.                "MCC" 170.000000 ###
#    12. "DifferenceVariance" 160.000000 ###
#    13.         "SumEntropy" 160.000000 ###
#    14.  "DifferenceAverage" 148.000000 ##
#    15.                "Idm" 137.000000 ##
#    16.                 "Id" 136.000000 ##
#    17.           "Contrast" 133.000000 ##
#    18.  "DifferenceEntropy" 115.000000 #
#    19.               "Imc2" 109.000000 #
#    20.  "ClusterProminence" 86.000000
#    21.       "JointEntropy" 86.000000
#    22.        "JointEnergy" 81.000000
#    23.    "ClusterTendency" 77.000000
#    24.         "SumSquares" 59.000000
#
# Variable Importance: SUM_SCORE:
#     1.    "Autocorrelation" 9496.625758 ################
#     2.    "InverseVariance" 1221.439254 ##
#     3.                "Idn" 1124.971972 #
#     4.               "Imc1" 540.376619
#     5.       "ClusterShade" 456.242765
#     6.         "SumAverage" 423.459298
#     7.               "Idmn" 403.150902
#     8.       "JointAverage" 316.373748
#     9.        "Correlation" 270.004305
#    10.                "Idm" 239.639113
#    11.                 "Id" 205.688367
#    12.               "Imc2" 193.273265
#    13.                "MCC" 182.860504
#    14.  "DifferenceEntropy" 182.345491
#    15.  "DifferenceAverage" 174.198418
#    16.           "Contrast" 172.875781
#    17. "MaximumProbability" 158.649819
#    18.         "SumEntropy" 158.181744
#    19. "DifferenceVariance" 121.318376
#    20.  "ClusterProminence" 82.846676
#    21.        "JointEnergy" 74.809306
#    22.    "ClusterTendency" 54.184138
#    23.         "SumSquares" 28.171695
#    24.       "JointEntropy" 24.984006
#
#
#
# Loss: BINOMIAL_LOG_LIKELIHOOD
# Validation loss value: 0.1951
# Number of trees per iteration: 1
# Node format: NOT_SET
# Number of trees: 201
# Total number of nodes: 9717
#
# Number of nodes by tree:
# Count: 201 Average: 48.3433 StdDev: 8.76484
# Min: 25 Max: 63 Ignored: 0
# ----------------------------------------------
# [ 25, 26)  1   0.50%   0.50%
# [ 26, 28)  1   0.50%   1.00%
# [ 28, 30)  2   1.00%   1.99% #
# [ 30, 32)  2   1.00%   2.99% #
# [ 32, 34)  7   3.48%   6.47% ###
# [ 34, 36) 10   4.98%  11.44% ####
# [ 36, 38)  8   3.98%  15.42% ###
# [ 38, 40)  9   4.48%  19.90% ####
# [ 40, 42)  6   2.99%  22.89% ##
# [ 42, 44) 15   7.46%  30.35% ######
# [ 44, 46) 14   6.97%  37.31% ######
# [ 46, 48) 12   5.97%  43.28% #####
# [ 48, 50) 25  12.44%  55.72% ##########
# [ 50, 52) 17   8.46%  64.18% #######
# [ 52, 54) 14   6.97%  71.14% ######
# [ 54, 56) 11   5.47%  76.62% ####
# [ 56, 58) 17   8.46%  85.07% #######
# [ 58, 60) 10   4.98%  90.05% ####
# [ 60, 62) 13   6.47%  96.52% #####
# [ 62, 63]  7   3.48% 100.00% ###
#
# Depth by leafs:
# Count: 4959 Average: 4.80298 StdDev: 0.564907
# Min: 1 Max: 5 Ignored: 0
# ----------------------------------------------
# [ 1, 2)    6   0.12%   0.12%
# [ 2, 3)   67   1.35%   1.47%
# [ 3, 4)  162   3.27%   4.74%
# [ 4, 5)  428   8.63%  13.37% #
# [ 5, 5] 4296  86.63% 100.00% ##########
#
# Number of training obs by leaf:
# Count: 4959 Average: 508.316 StdDev: 1297.43
# Min: 5 Max: 11600 Ignored: 0
# ----------------------------------------------
# [     5,   584) 4073  82.13%  82.13% ##########
# [   584,  1164)  297   5.99%  88.12% #
# [  1164,  1744)  184   3.71%  91.83%
# [  1744,  2324)   97   1.96%  93.79%
# [  2324,  2904)   64   1.29%  95.08%
# [  2904,  3483)   57   1.15%  96.23%
# [  3483,  4063)   32   0.65%  96.87%
# [  4063,  4643)   23   0.46%  97.34%
# [  4643,  5223)   25   0.50%  97.84%
# [  5223,  5803)   23   0.46%  98.31%
# [  5803,  6382)   15   0.30%  98.61%
# [  6382,  6962)   20   0.40%  99.01%
# [  6962,  7542)   12   0.24%  99.25%
# [  7542,  8122)    7   0.14%  99.40%
# [  8122,  8702)   11   0.22%  99.62%
# [  8702,  9281)    5   0.10%  99.72%
# [  9281,  9861)    2   0.04%  99.76%
# [  9861, 10441)    4   0.08%  99.84%
# [ 10441, 11021)    3   0.06%  99.90%
# [ 11021, 11600]    5   0.10% 100.00%
#
# Attribute in nodes:
# 	545 : Autocorrelation [NUMERICAL]
# 	525 : Idn [NUMERICAL]
# 	370 : ClusterShade [NUMERICAL]
# 	291 : InverseVariance [NUMERICAL]
# 	286 : SumAverage [NUMERICAL]
# 	282 : JointAverage [NUMERICAL]
# 	217 : Correlation [NUMERICAL]
# 	216 : Idmn [NUMERICAL]
# 	190 : MaximumProbability [NUMERICAL]
# 	179 : Imc1 [NUMERICAL]
# 	170 : MCC [NUMERICAL]
# 	160 : SumEntropy [NUMERICAL]
# 	160 : DifferenceVariance [NUMERICAL]
# 	148 : DifferenceAverage [NUMERICAL]
# 	137 : Idm [NUMERICAL]
# 	136 : Id [NUMERICAL]
# 	133 : Contrast [NUMERICAL]
# 	115 : DifferenceEntropy [NUMERICAL]
# 	109 : Imc2 [NUMERICAL]
# 	86 : JointEntropy [NUMERICAL]
# 	86 : ClusterProminence [NUMERICAL]
# 	81 : JointEnergy [NUMERICAL]
# 	77 : ClusterTendency [NUMERICAL]
# 	59 : SumSquares [NUMERICAL]
#
# Attribute in nodes with depth <= 0:
# 	54 : Autocorrelation [NUMERICAL]
# 	38 : SumAverage [NUMERICAL]
# 	32 : JointAverage [NUMERICAL]
# 	25 : Idn [NUMERICAL]
# 	14 : Imc1 [NUMERICAL]
# 	14 : Correlation [NUMERICAL]
# 	11 : InverseVariance [NUMERICAL]
# 	7 : Idmn [NUMERICAL]
# 	6 : Id [NUMERICAL]
#
# Attribute in nodes with depth <= 1:
# 	112 : Autocorrelation [NUMERICAL]
# 	73 : JointAverage [NUMERICAL]
# 	63 : SumAverage [NUMERICAL]
# 	61 : Idn [NUMERICAL]
# 	54 : InverseVariance [NUMERICAL]
# 	36 : Correlation [NUMERICAL]
# 	34 : ClusterShade [NUMERICAL]
# 	20 : Imc1 [NUMERICAL]
# 	18 : Id [NUMERICAL]
# 	15 : Idmn [NUMERICAL]
# 	15 : DifferenceAverage [NUMERICAL]
# 	14 : DifferenceEntropy [NUMERICAL]
# 	13 : DifferenceVariance [NUMERICAL]
# 	11 : ClusterTendency [NUMERICAL]
# 	10 : MaximumProbability [NUMERICAL]
# 	9 : Idm [NUMERICAL]
# 	9 : Contrast [NUMERICAL]
# 	8 : Imc2 [NUMERICAL]
# 	7 : SumEntropy [NUMERICAL]
# 	6 : MCC [NUMERICAL]
# 	3 : SumSquares [NUMERICAL]
# 	3 : ClusterProminence [NUMERICAL]
# 	2 : JointEntropy [NUMERICAL]
# 	1 : JointEnergy [NUMERICAL]
#
# Attribute in nodes with depth <= 2:
# 	192 : Autocorrelation [NUMERICAL]
# 	178 : Idn [NUMERICAL]
# 	109 : JointAverage [NUMERICAL]
# 	95 : SumAverage [NUMERICAL]
# 	89 : InverseVariance [NUMERICAL]
# 	84 : ClusterShade [NUMERICAL]
# 	74 : Correlation [NUMERICAL]
# 	53 : Imc1 [NUMERICAL]
# 	49 : MaximumProbability [NUMERICAL]
# 	39 : Id [NUMERICAL]
# 	38 : Idmn [NUMERICAL]
# 	36 : DifferenceAverage [NUMERICAL]
# 	35 : DifferenceVariance [NUMERICAL]
# 	33 : SumEntropy [NUMERICAL]
# 	33 : MCC [NUMERICAL]
# 	30 : DifferenceEntropy [NUMERICAL]
# 	29 : Idm [NUMERICAL]
# 	28 : Contrast [NUMERICAL]
# 	24 : JointEntropy [NUMERICAL]
# 	24 : ClusterTendency [NUMERICAL]
# 	21 : Imc2 [NUMERICAL]
# 	10 : SumSquares [NUMERICAL]
# 	10 : ClusterProminence [NUMERICAL]
# 	9 : JointEnergy [NUMERICAL]
#
# Attribute in nodes with depth <= 3:
# 	332 : Autocorrelation [NUMERICAL]
# 	316 : Idn [NUMERICAL]
# 	189 : ClusterShade [NUMERICAL]
# 	173 : JointAverage [NUMERICAL]
# 	165 : InverseVariance [NUMERICAL]
# 	162 : SumAverage [NUMERICAL]
# 	113 : Correlation [NUMERICAL]
# 	106 : Idmn [NUMERICAL]
# 	98 : MaximumProbability [NUMERICAL]
# 	98 : DifferenceVariance [NUMERICAL]
# 	91 : Imc1 [NUMERICAL]
# 	85 : MCC [NUMERICAL]
# 	79 : Idm [NUMERICAL]
# 	76 : SumEntropy [NUMERICAL]
# 	76 : DifferenceAverage [NUMERICAL]
# 	72 : Id [NUMERICAL]
# 	70 : Contrast [NUMERICAL]
# 	61 : DifferenceEntropy [NUMERICAL]
# 	50 : Imc2 [NUMERICAL]
# 	47 : JointEntropy [NUMERICAL]
# 	46 : ClusterProminence [NUMERICAL]
# 	44 : ClusterTendency [NUMERICAL]
# 	33 : SumSquares [NUMERICAL]
# 	28 : JointEnergy [NUMERICAL]
#
# Attribute in nodes with depth <= 5:
# 	545 : Autocorrelation [NUMERICAL]
# 	525 : Idn [NUMERICAL]
# 	370 : ClusterShade [NUMERICAL]
# 	291 : InverseVariance [NUMERICAL]
# 	286 : SumAverage [NUMERICAL]
# 	282 : JointAverage [NUMERICAL]
# 	217 : Correlation [NUMERICAL]
# 	216 : Idmn [NUMERICAL]
# 	190 : MaximumProbability [NUMERICAL]
# 	179 : Imc1 [NUMERICAL]
# 	170 : MCC [NUMERICAL]
# 	160 : SumEntropy [NUMERICAL]
# 	160 : DifferenceVariance [NUMERICAL]
# 	148 : DifferenceAverage [NUMERICAL]
# 	137 : Idm [NUMERICAL]
# 	136 : Id [NUMERICAL]
# 	133 : Contrast [NUMERICAL]
# 	115 : DifferenceEntropy [NUMERICAL]
# 	109 : Imc2 [NUMERICAL]
# 	86 : JointEntropy [NUMERICAL]
# 	86 : ClusterProminence [NUMERICAL]
# 	81 : JointEnergy [NUMERICAL]
# 	77 : ClusterTendency [NUMERICAL]
# 	59 : SumSquares [NUMERICAL]
#
# Condition type in nodes:
# 	4758 : HigherCondition
# Condition type in nodes with depth <= 0:
# 	201 : HigherCondition
# Condition type in nodes with depth <= 1:
# 	597 : HigherCondition
# Condition type in nodes with depth <= 2:
# 	1322 : HigherCondition
# Condition type in nodes with depth <= 3:
# 	2610 : HigherCondition
# Condition type in nodes with depth <= 5:
# 	4758 : HigherCondition
#
# Training logs:
# Number of iteration to final model: 201
# 	Iter:1 train-loss:1.244390 valid-loss:1.253794  train-accuracy:0.917504 valid-accuracy:0.899884
# 	Iter:2 train-loss:1.123816 valid-loss:1.134046  train-accuracy:0.938590 valid-accuracy:0.928127
# 	Iter:3 train-loss:1.022751 valid-loss:1.033162  train-accuracy:0.942072 valid-accuracy:0.932230
# 	Iter:4 train-loss:0.934558 valid-loss:0.950591  train-accuracy:0.948314 valid-accuracy:0.932640
# 	Iter:5 train-loss:0.858809 valid-loss:0.877790  train-accuracy:0.943781 valid-accuracy:0.923477
# 	Iter:6 train-loss:0.793318 valid-loss:0.818923  train-accuracy:0.945038 valid-accuracy:0.921425
# 	Iter:16 train-loss:0.431705 valid-loss:0.496077  train-accuracy:0.961923 valid-accuracy:0.943787
# 	Iter:26 train-loss:0.290091 valid-loss:0.372201  train-accuracy:0.975813 valid-accuracy:0.942078
# 	Iter:36 train-loss:0.216471 valid-loss:0.320561  train-accuracy:0.981583 valid-accuracy:0.943719
# 	Iter:46 train-loss:0.168936 valid-loss:0.281036  train-accuracy:0.986914 valid-accuracy:0.947822
# 	Iter:56 train-loss:0.133551 valid-loss:0.257408  train-accuracy:0.990495 valid-accuracy:0.949874
# 	Iter:66 train-loss:0.110298 valid-loss:0.240119  train-accuracy:0.992105 valid-accuracy:0.957328
# 	Iter:76 train-loss:0.094347 valid-loss:0.228869  train-accuracy:0.993849 valid-accuracy:0.957738
# 	Iter:86 train-loss:0.079811 valid-loss:0.220979  train-accuracy:0.995678 valid-accuracy:0.958559
# 	Iter:96 train-loss:0.070441 valid-loss:0.219804  train-accuracy:0.996187 valid-accuracy:0.959379
# 	Iter:106 train-loss:0.062022 valid-loss:0.215114  train-accuracy:0.996356 valid-accuracy:0.955208
# 	Iter:116 train-loss:0.055500 valid-loss:0.213628  train-accuracy:0.996992 valid-accuracy:0.955208
# 	Iter:126 train-loss:0.049399 valid-loss:0.209176  train-accuracy:0.997458 valid-accuracy:0.949805
# 	Iter:136 train-loss:0.044093 valid-loss:0.209000  train-accuracy:0.997797 valid-accuracy:0.956028
# 	Iter:146 train-loss:0.039950 valid-loss:0.208804  train-accuracy:0.998051 valid-accuracy:0.956439
# 	Iter:156 train-loss:0.036208 valid-loss:0.207134  train-accuracy:0.998348 valid-accuracy:0.950626
# 	Iter:166 train-loss:0.032056 valid-loss:0.201008  train-accuracy:0.998771 valid-accuracy:0.962251
# 	Iter:176 train-loss:0.029003 valid-loss:0.200665  train-accuracy:0.998941 valid-accuracy:0.962662
# 	Iter:186 train-loss:0.026427 valid-loss:0.196607  train-accuracy:0.999195 valid-accuracy:0.962662
# 	Iter:196 train-loss:0.024128 valid-loss:0.195333  train-accuracy:0.999407 valid-accuracy:0.963072
# 	Iter:206 train-loss:0.021897 valid-loss:0.199326  train-accuracy:0.999576 valid-accuracy:0.957670
# 	Iter:216 train-loss:0.019909 valid-loss:0.198703  train-accuracy:0.999661 valid-accuracy:0.957670
# 	Iter:226 train-loss:0.018241 valid-loss:0.202022  train-accuracy:0.999831 valid-accuracy:0.963072

# %%
# Model features
model.make_inspector().features()
# Out:
# ["Autocorrelation" (1; #0),
#  "ClusterProminence" (1; #1),
#  "ClusterShade" (1; #2),
#  "ClusterTendency" (1; #3),
#  "Contrast" (1; #4),
#  "Correlation" (1; #5),
#  "DifferenceAverage" (1; #6),
#  "DifferenceEntropy" (1; #7),
#  "DifferenceVariance" (1; #8),
#  "Id" (1; #9),
#  "Idm" (1; #10),
#  "Idmn" (1; #11),
#  "Idn" (1; #12),
#  "Imc1" (1; #13),
#  "Imc2" (1; #14),
#  "InverseVariance" (1; #15),
#  "JointAverage" (1; #16),
#  "JointEnergy" (1; #17),
#  "JointEntropy" (1; #18),
#  "MCC" (1; #19),
#  "MaximumProbability" (1; #20),
#  "SumAverage" (1; #21),
#  "SumEntropy" (1; #22),
#  "SumSquares" (1; #23)]

# %%
# Feature importance
model.make_inspector().variable_importances()
# Out:
# {'INV_MEAN_MIN_DEPTH': [("Autocorrelation" (1; #0), 0.2555481759297892),
#   ("Idn" (1; #12), 0.23600665849432198),
#   ("SumAverage" (1; #21), 0.22030095251309761),
#   ("JointAverage" (1; #16), 0.21827484286628196),
#   ("InverseVariance" (1; #15), 0.20427640552943258),
#   ("ClusterShade" (1; #2), 0.19538752306851875),
#   ("Correlation" (1; #5), 0.19443185136397512),
#   ("Imc1" (1; #13), 0.1925206606207031),
#   ("Idmn" (1; #11), 0.18737274148634697),
#   ("Id" (1; #9), 0.18625348522781177),
#   ("DifferenceAverage" (1; #6), 0.1831087486736004),
#   ("DifferenceVariance" (1; #8), 0.18282419967694868),
#   ("MaximumProbability" (1; #20), 0.1827662492003615),
#   ("DifferenceEntropy" (1; #7), 0.18158303248043656),
#   ("Idm" (1; #10), 0.18112722505722773),
#   ("Contrast" (1; #4), 0.180903618848751),
#   ("MCC" (1; #19), 0.18046823546502605),
#   ("SumEntropy" (1; #22), 0.17993355865098834),
#   ("Imc2" (1; #14), 0.17874843904765528),
#   ("ClusterTendency" (1; #3), 0.17853047176285097),
#   ("JointEntropy" (1; #18), 0.17708750764309825),
#   ("ClusterProminence" (1; #1), 0.17671470635524134),
#   ("JointEnergy" (1; #17), 0.17565360291809773),
#   ("SumSquares" (1; #23), 0.17537118764134166)],
#  'NUM_AS_ROOT': [("Autocorrelation" (1; #0), 54.0),
#   ("SumAverage" (1; #21), 38.0),
#   ("JointAverage" (1; #16), 32.0),
#   ("Idn" (1; #12), 25.0),
#   ("Correlation" (1; #5), 14.0),
#   ("Imc1" (1; #13), 14.0),
#   ("InverseVariance" (1; #15), 11.0),
#   ("Idmn" (1; #11), 7.0),
#   ("Id" (1; #9), 6.0)],
#  'SUM_SCORE': [("Autocorrelation" (1; #0), 9496.62575822184),
#   ("InverseVariance" (1; #15), 1221.4392536734488),
#   ("Idn" (1; #12), 1124.9719716470718),
#   ("Imc1" (1; #13), 540.3766193711059),
#   ("ClusterShade" (1; #2), 456.2427651498567),
#   ("SumAverage" (1; #21), 423.4592983672021),
#   ("Idmn" (1; #11), 403.15090180224627),
#   ("JointAverage" (1; #16), 316.3737481035742),
#   ("Correlation" (1; #5), 270.004305359156),
#   ("Idm" (1; #10), 239.6391127729802),
#   ("Id" (1; #9), 205.68836749132558),
#   ("Imc2" (1; #14), 193.27326500256396),
#   ("MCC" (1; #19), 182.86050403041375),
#   ("DifferenceEntropy" (1; #7), 182.34549056250444),
#   ("DifferenceAverage" (1; #6), 174.19841815911812),
#   ("Contrast" (1; #4), 172.87578082836154),
#   ("MaximumProbability" (1; #20), 158.64981937881944),
#   ("SumEntropy" (1; #22), 158.18174410682394),
#   ("DifferenceVariance" (1; #8), 121.31837617177523),
#   ("ClusterProminence" (1; #1), 82.84667556159403),
#   ("JointEnergy" (1; #17), 74.80930567118432),
#   ("ClusterTendency" (1; #3), 54.184137841782864),
#   ("SumSquares" (1; #23), 28.171695127596518),
#   ("JointEntropy" (1; #18), 24.98400575338687)],
#  'NUM_NODES': [("Autocorrelation" (1; #0), 545.0),
#   ("Idn" (1; #12), 525.0),
#   ("ClusterShade" (1; #2), 370.0),
#   ("InverseVariance" (1; #15), 291.0),
#   ("SumAverage" (1; #21), 286.0),
#   ("JointAverage" (1; #16), 282.0),
#   ("Correlation" (1; #5), 217.0),
#   ("Idmn" (1; #11), 216.0),
#   ("MaximumProbability" (1; #20), 190.0),
#   ("Imc1" (1; #13), 179.0),
#   ("MCC" (1; #19), 170.0),
#   ("DifferenceVariance" (1; #8), 160.0),
#   ("SumEntropy" (1; #22), 160.0),
#   ("DifferenceAverage" (1; #6), 148.0),
#   ("Idm" (1; #10), 137.0),
#   ("Id" (1; #9), 136.0),
#   ("Contrast" (1; #4), 133.0),
#   ("DifferenceEntropy" (1; #7), 115.0),
#   ("Imc2" (1; #14), 109.0),
#   ("ClusterProminence" (1; #1), 86.0),
#   ("JointEntropy" (1; #18), 86.0),
#   ("JointEnergy" (1; #17), 81.0),
#   ("ClusterTendency" (1; #3), 77.0),
#   ("SumSquares" (1; #23), 59.0)]}

# %%
# Model self evaluation
model.make_inspector().evaluation()
# Out:
# Evaluation(num_examples=None, accuracy=0.9576696753501892, loss=0.1950998157262802, rmse=None, ndcg=None, aucs=None, auuc=None, qini=None)

# %%
logs = model.make_inspector().training_logs()

plt.figure(figsize=(12, 4))
plt.subplot(1, 2, 1)
plt.plot([log.num_trees for log in logs], [log.evaluation.accuracy for log in logs])
plt.xlabel("Number of trees")
plt.ylabel("Accuracy (out-of-bag)")
plt.subplot(1, 2, 2)
plt.plot([log.num_trees for log in logs], [log.evaluation.loss for log in logs])
plt.xlabel("Number of trees")
plt.ylabel("Logloss (out-of-bag)")
plt.show()

# %% [markdown]
# Calculate the score of our hold-out validation dataset

# %%
predictions = model.predict(val_ds)
y_true      = validation_data["label"]

from sklearn.metrics import roc_auc_score
ROC_AUC = roc_auc_score(y_true, predictions)
print("The ROC AUC score is %.5f" % ROC_AUC )
# Out:
# 1/2 [==============>...............] - ETA: 0s
# 2/2 [==============================] - 0s 7ms/step
# The ROC AUC score is 0.99810

# %%
# Compute binary classification metrics with sklearn
import numpy as np
from sklearn.metrics import (
    accuracy_score,
    precision_score,
    recall_score,
    f1_score,
    roc_auc_score,
    average_precision_score,
    confusion_matrix,
    classification_report,
    matthews_corrcoef,
    log_loss,
    brier_score_loss,
)

# Get predictions (probabilities or class labels)
preds = model.predict(test_ds)
# If model outputs probabilities, convert to labels by threshold 0.5
if preds.ndim == 2:
    # For TFDF classification, preds may be class probabilities with shape (N, 2)
    if preds.shape[1] == 2:
        pos_probs = preds[:, 1]
    else:
        # If single-probability column (positive class)
        pos_probs = preds[:, -1]
    y_pred = (pos_probs >= 0.5).astype(int)
else:
    # Already class labels
    y_pred = preds.astype(int)
    pos_probs = None

# Ground truth labels (must be 0/1 integers)
y_true = test_data["label"].astype(int).to_numpy()

# Core metrics
metrics = {}
metrics["accuracy"] = accuracy_score(y_true, y_pred)
metrics["precision"] = precision_score(y_true, y_pred, zero_division=0)
metrics["recall"] = recall_score(y_true, y_pred, zero_division=0)
metrics["f1"] = f1_score(y_true, y_pred, zero_division=0)
metrics["mcc"] = matthews_corrcoef(y_true, y_pred)

# Probabilistic metrics (only if we have probabilities)
if pos_probs is not None:
    metrics["roc_auc"] = roc_auc_score(y_true, pos_probs)
    metrics["pr_auc"] = average_precision_score(y_true, pos_probs)
    metrics["log_loss"] = log_loss(y_true, pos_probs, labels=[0,1])
    metrics["brier_score"] = brier_score_loss(y_true, pos_probs)

# Confusion matrix and detailed report
cm = confusion_matrix(y_true, y_pred, labels=[0,1])
report = classification_report(y_true, y_pred, digits=4)

print("Sklearn binary metrics:")
for k, v in metrics.items():
    print(f"{k}: {v:.4f}")
print("\nConfusion matrix:\n", cm)
print("\nClassification report:\n", report)
# Out:
# 1/5 [=====>........................] - ETA: 0s
# 5/5 [==============================] - 0s 5ms/step
# Sklearn binary metrics:
# accuracy: 0.9603
# precision: 0.7618
# recall: 0.8659
# f1: 0.8105
# mcc: 0.7904
# roc_auc: 0.9727
# pr_auc: 0.8845
# log_loss: 0.1291
# brier_score: 0.0328
#
# Confusion matrix:
#  [[3658  111]
#  [  55  355]]
#
# Classification report:
#                precision    recall  f1-score   support
#
#            0     0.9852    0.9705    0.9778      3769
#            1     0.7618    0.8659    0.8105       410
#
#     accuracy                         0.9603      4179
#    macro avg     0.8735    0.9182    0.8942      4179
# weighted avg     0.9633    0.9603    0.9614      4179
