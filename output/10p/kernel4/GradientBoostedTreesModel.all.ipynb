# %%
# Import packages and modules
import numpy  as np
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow_decision_forests as tfdf

from sklearn.model_selection import train_test_split
# Out:
# 2026-09-11 08:09:25.252905: I tensorflow/core/util/port.cc:113] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2026-09-11 08:09:25.309693: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2026-09-11 08:09:30.944750: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
# Check the version of TensorFlow Decision Forests
print("Found TensorFlow Decision Forests v" + tfdf.__version__)
# Out:
# Found TensorFlow Decision Forests v1.9.1

# %%
datasetPath = "dataset/10p/all/kernel3/"

# %%
# Parameters
datasetPath = "dataset/10p/all/kernel4/"

# %%
# train/validation/test = 70/10/20
train_data = pd.read_csv(f"{datasetPath}dataset.train.csv")
validation_data = pd.read_csv(f"{datasetPath}dataset.validation.csv")
test_data = pd.read_csv(f"{datasetPath}dataset.test.csv")

# %%
from sklearn.utils.class_weight import compute_class_weight

# tinh class weight tren tap train
classes = np.array([0, 1])
weights = compute_class_weight(class_weight="balanced", classes=classes, y=train_data["label"])
class_weight = {0: weights[0], 1: weights[1]}

# gan sample_weight cho tung dong
train_data["sample_weight"] = train_data["label"].map(class_weight)
validation_data["sample_weight"] = validation_data["label"].map(class_weight)
test_data["sample_weight"] = test_data["label"].map(class_weight)

# Convert the dataset into a TensorFlow dataset.
train_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    train_data, label="label", weight="sample_weight"
)         
val_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    validation_data, label="label", weight="sample_weight"
)
test_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    test_data, label="label", weight="sample_weight"
)
# Out:
# 2026-09-11 08:09:47.861133: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:984] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2026-09-11 08:09:47.862971: W tensorflow/core/common_runtime/gpu/gpu_device.cc:2251] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...

# %%
import keras

# %%
# %%time

# Train a Gradient Boosted Trees model.
model = tfdf.keras.GradientBoostedTreesModel()

# Add evaluation metrics
model.compile(
    metrics=["accuracy"]
)
model.fit(x=train_ds)

# # Train a Gradient Boosted Trees model.
# model = tfdf.keras.GradientBoostedTreesModel(num_trees=1500)
# model.fit(train_ds)
# Out:
# Use /tmp/tmpnsppz3pe as temporary training directory
# Reading training dataset...
# [WARNING 26-09-11 08:09:48.1877 UTC gradient_boosted_trees.cc:1840] "goss_alpha" set but "sampling_method" not equal to "GOSS".
# [WARNING 26-09-11 08:09:48.1882 UTC gradient_boosted_trees.cc:1851] "goss_beta" set but "sampling_method" not equal to "GOSS".
# [WARNING 26-09-11 08:09:48.1883 UTC gradient_boosted_trees.cc:1865] "selective_gradient_boosting_ratio" set but "sampling_method" not equal to "SELGB".
# Training dataset read in 0:00:04.165749. Found 13938 examples.
# Training model...
# Model trained in 0:00:04.357033
# Compiling model...
# [INFO 26-09-11 08:09:56.7437 UTC kernel.cc:1233] Loading model from path /tmp/tmpnsppz3pe/model/ with prefix 95bdd368fa6c4fd5
# [INFO 26-09-11 08:09:56.7482 UTC quick_scorer_extended.cc:911] The binary was compiled without AVX2 support, but your CPU supports it. Enable it for faster model inference.
# [INFO 26-09-11 08:09:56.7485 UTC abstract_model.cc:1362] Engine "GradientBoostedTreesQuickScorerExtended" built
# [INFO 26-09-11 08:09:56.7486 UTC kernel.cc:1061] Use fast generic engine
# Model compiled.
# CPU times: user 38.7 s, sys: 2.37 s, total: 41.1 s
# Wall time: 13 s

# %%
# Evaluate the model
evaluate = model.evaluate(val_ds, return_dict=True)
print()

for name, value in evaluate.items():
    print(f"{name}: {value:.4f}")
# Out:
# WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 1/2 [==============>...............] - ETA: 3s - loss: 0.0000e+00 - accuracy: 0.9840
# 2/2 [==============================] - 4s 33ms/step - loss: 0.0000e+00 - accuracy: 0.9872
# loss: 0.0000
# accuracy: 0.9872

# %%
# Model Summary
model.summary()
# Out:
# Model: "gradient_boosted_trees_model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
# =================================================================
# Total params: 1 (1.00 Byte)
# Trainable params: 0 (0.00 Byte)
# Non-trainable params: 1 (1.00 Byte)
# _________________________________________________________________
# Type: "GRADIENT_BOOSTED_TREES"
# Task: CLASSIFICATION
# Label: "__LABEL"
#
# Input Features (93):
# 	10Percentile
# 	90Percentile
# 	Autocorrelation
# 	Busyness
# 	ClusterProminence
# 	ClusterShade
# 	ClusterTendency
# 	Coarseness
# 	Complexity
# 	Contrast
# 	Contrast.1
# 	Correlation
# 	DependenceEntropy
# 	DependenceNonUniformity
# 	DependenceNonUniformityNormalized
# 	DependenceVariance
# 	DifferenceAverage
# 	DifferenceEntropy
# 	DifferenceVariance
# 	Energy
# 	Entropy
# 	GrayLevelNonUniformity
# 	GrayLevelNonUniformity.1
# 	GrayLevelNonUniformity.2
# 	GrayLevelNonUniformityNormalized
# 	GrayLevelNonUniformityNormalized.1
# 	GrayLevelVariance
# 	GrayLevelVariance.1
# 	GrayLevelVariance.2
# 	HighGrayLevelEmphasis
# 	HighGrayLevelRunEmphasis
# 	HighGrayLevelZoneEmphasis
# 	Id
# 	Idm
# 	Idmn
# 	Idn
# 	Imc1
# 	Imc2
# 	InterquartileRange
# 	InverseVariance
# 	JointAverage
# 	JointEnergy
# 	JointEntropy
# 	Kurtosis
# 	LargeAreaEmphasis
# 	LargeAreaHighGrayLevelEmphasis
# 	LargeAreaLowGrayLevelEmphasis
# 	LargeDependenceEmphasis
# 	LargeDependenceHighGrayLevelEmphasis
# 	LargeDependenceLowGrayLevelEmphasis
# 	LongRunEmphasis
# 	LongRunHighGrayLevelEmphasis
# 	LongRunLowGrayLevelEmphasis
# 	LowGrayLevelEmphasis
# 	LowGrayLevelRunEmphasis
# 	LowGrayLevelZoneEmphasis
# 	MCC
# 	Maximum
# 	MaximumProbability
# 	Mean
# 	MeanAbsoluteDeviation
# 	Median
# 	Minimum
# 	Range
# 	RobustMeanAbsoluteDeviation
# 	RootMeanSquared
# 	RunEntropy
# 	RunLengthNonUniformity
# 	RunLengthNonUniformityNormalized
# 	RunPercentage
# 	RunVariance
# 	ShortRunEmphasis
# 	ShortRunHighGrayLevelEmphasis
# 	ShortRunLowGrayLevelEmphasis
# 	SizeZoneNonUniformity
# 	SizeZoneNonUniformityNormalized
# 	Skewness
# 	SmallAreaEmphasis
# 	SmallAreaHighGrayLevelEmphasis
# 	SmallAreaLowGrayLevelEmphasis
# 	SmallDependenceEmphasis
# 	SmallDependenceHighGrayLevelEmphasis
# 	SmallDependenceLowGrayLevelEmphasis
# 	Strength
# 	SumAverage
# 	SumEntropy
# 	SumSquares
# 	TotalEnergy
# 	Uniformity
# 	Variance
# 	ZoneEntropy
# 	ZonePercentage
# 	ZoneVariance
#
# Trained with weights
#
# Variable Importance: INV_MEAN_MIN_DEPTH:
#     1. "LargeDependenceHighGrayLevelEmphasis"  0.276195 ################
#     2.         "LongRunHighGrayLevelEmphasis"  0.264082 ##############
#     3.                                  "Idn"  0.220660 #######
#     4.                             "Busyness"  0.209098 #####
#     5.                           "Coarseness"  0.200783 ####
#     6.                              "Maximum"  0.193254 ###
#     7.                             "Skewness"  0.182814 #
#     8.             "GrayLevelNonUniformity.2"  0.181466 #
#     9.       "LargeAreaHighGrayLevelEmphasis"  0.180059 #
#    10.                         "ClusterShade"  0.179396 #
#    11.                         "90Percentile"  0.178440 #
#    12.  "SmallDependenceLowGrayLevelEmphasis"  0.177255 #
#    13.                                 "Idmn"  0.176698 #
#    14.                               "Median"  0.176467 #
#    15.       "SmallAreaHighGrayLevelEmphasis"  0.175494
#    16. "SmallDependenceHighGrayLevelEmphasis"  0.174231
#    17.                      "InverseVariance"  0.173200
#    18.                    "SmallAreaEmphasis"  0.173026
#    19.                          "TotalEnergy"  0.172663
#    20.                "HighGrayLevelEmphasis"  0.172393
#    21.                    "DependenceEntropy"  0.172193
#    22.             "HighGrayLevelRunEmphasis"  0.171695
#    23.            "HighGrayLevelZoneEmphasis"  0.171667
#    24.  "LargeDependenceLowGrayLevelEmphasis"  0.171361
#    25.                           "Contrast.1"  0.171292
#    26.                  "GrayLevelVariance.2"  0.171227
#    27.                             "Kurtosis"  0.171189
#    28.      "SizeZoneNonUniformityNormalized"  0.171180
#    29.                   "DifferenceVariance"  0.171059
#    30.                         "10Percentile"  0.171016
#    31.                 "LowGrayLevelEmphasis"  0.171006
#    32.        "ShortRunHighGrayLevelEmphasis"  0.170938
#    33.    "DependenceNonUniformityNormalized"  0.170806
#    34.                           "SumAverage"  0.170787
#    35.                             "Contrast"  0.170750
#    36.                      "LongRunEmphasis"  0.170733
#    37.                "SizeZoneNonUniformity"  0.170725
#    38.                                 "Mean"  0.170620
#    39.                                 "Imc2"  0.170603
#    40.                                  "MCC"  0.170593
#    41.                      "Autocorrelation"  0.170542
#    42.                          "JointEnergy"  0.170495
#    43.                   "MaximumProbability"  0.170483
#    44.                                "Range"  0.170460
#    45.             "LowGrayLevelZoneEmphasis"  0.170456
#    46.                                 "Imc1"  0.170437
#    47.                           "RunEntropy"  0.170378
#    48.                         "JointAverage"  0.170338
#    49.                             "Strength"  0.170332
#    50.                           "Complexity"  0.170325
#    51.   "GrayLevelNonUniformityNormalized.1"  0.170310
#    52.                              "Minimum"  0.170306
#    53.                          "Correlation"  0.170256
#    54.                          "ZoneEntropy"  0.170238
#    55.                    "ClusterProminence"  0.170221
#    56.                    "DifferenceEntropy"  0.170168
#    57.        "LargeAreaLowGrayLevelEmphasis"  0.170117
#    58.                      "RootMeanSquared"  0.170088
#    59.                    "DifferenceAverage"  0.170062
#    60.          "LongRunLowGrayLevelEmphasis"  0.170042
#    61.               "GrayLevelNonUniformity"  0.170024
#    62.              "SmallDependenceEmphasis"  0.169973
#    63.                           "Uniformity"  0.169953
#    64.        "SmallAreaLowGrayLevelEmphasis"  0.169949
#    65.                        "RunPercentage"  0.169946
#    66.                         "ZoneVariance"  0.169922
#    67.              "LowGrayLevelRunEmphasis"  0.169900
#    68.                       "ZonePercentage"  0.169891
#    69.     "GrayLevelNonUniformityNormalized"  0.169865
#    70.         "ShortRunLowGrayLevelEmphasis"  0.169844
#    71.                           "SumSquares"  0.169835
#    72.                          "RunVariance"  0.169824
#    73.                         "JointEntropy"  0.169811
#    74.                           "SumEntropy"  0.169797
#    75.                   "DependenceVariance"  0.169761
#    76.                                   "Id"  0.169756
#    77.              "LargeDependenceEmphasis"  0.169743
#    78.                      "ClusterTendency"  0.169738
#    79.     "RunLengthNonUniformityNormalized"  0.169735
#    80.                               "Energy"  0.169715
#    81.                   "InterquartileRange"  0.169708
#    82.                  "GrayLevelVariance.1"  0.169701
#    83.                                  "Idm"  0.169678
#    84.                "MeanAbsoluteDeviation"  0.169657
#    85.                             "Variance"  0.169657
#    86.             "GrayLevelNonUniformity.1"  0.169654
#    87.               "RunLengthNonUniformity"  0.169644
#    88.              "DependenceNonUniformity"  0.169643
#    89.                    "GrayLevelVariance"  0.169639
#    90.                              "Entropy"  0.169638
#
# Variable Importance: NUM_AS_ROOT:
#     1.         "LongRunHighGrayLevelEmphasis" 22.000000 ################
#     2. "LargeDependenceHighGrayLevelEmphasis" 14.000000 #########
#     3.                             "Busyness"  8.000000 #####
#     4.                           "Coarseness"  3.000000 #
#     5.                              "Maximum"  3.000000 #
#     6.                "HighGrayLevelEmphasis"  1.000000
#     7.                          "TotalEnergy"  1.000000
#
# Variable Importance: NUM_NODES:
#     1.                                  "Idn" 167.000000 ################
#     2. "LargeDependenceHighGrayLevelEmphasis" 105.000000 ##########
#     3.                           "Coarseness" 80.000000 #######
#     4.         "LongRunHighGrayLevelEmphasis" 71.000000 ######
#     5.                             "Busyness" 61.000000 #####
#     6.                             "Skewness" 55.000000 #####
#     7.             "GrayLevelNonUniformity.2" 51.000000 ####
#     8.                              "Maximum" 51.000000 ####
#     9.       "LargeAreaHighGrayLevelEmphasis" 50.000000 ####
#    10.                                 "Idmn" 47.000000 ####
#    11.                         "90Percentile" 45.000000 ####
#    12.                         "ClusterShade" 43.000000 ####
#    13.                               "Median" 33.000000 ###
#    14.       "SmallAreaHighGrayLevelEmphasis" 31.000000 ##
#    15.  "LargeDependenceLowGrayLevelEmphasis" 29.000000 ##
#    16.  "SmallDependenceLowGrayLevelEmphasis" 29.000000 ##
#    17.                    "DependenceEntropy" 23.000000 ##
#    18. "SmallDependenceHighGrayLevelEmphasis" 23.000000 ##
#    19.                           "Contrast.1" 19.000000 #
#    20.                      "InverseVariance" 18.000000 #
#    21.                         "10Percentile" 16.000000 #
#    22.            "HighGrayLevelZoneEmphasis" 16.000000 #
#    23.                             "Kurtosis" 16.000000 #
#    24.                   "DifferenceVariance" 15.000000 #
#    25.                             "Contrast" 12.000000 #
#    26.      "SizeZoneNonUniformityNormalized" 12.000000 #
#    27.                           "Complexity" 11.000000
#    28.                  "GrayLevelVariance.2" 11.000000
#    29.                                  "MCC" 11.000000
#    30.                      "Autocorrelation" 10.000000
#    31.                          "Correlation" 10.000000
#    32.             "LowGrayLevelZoneEmphasis" 10.000000
#    33.        "ShortRunHighGrayLevelEmphasis" 10.000000
#    34.                    "ClusterProminence"  9.000000
#    35.                                 "Imc1"  9.000000
#    36.        "LargeAreaLowGrayLevelEmphasis"  9.000000
#    37.                              "Minimum"  9.000000
#    38.                                "Range"  9.000000
#    39.                          "JointEnergy"  8.000000
#    40.          "LongRunLowGrayLevelEmphasis"  8.000000
#    41.                                 "Mean"  8.000000
#    42.                    "DifferenceAverage"  7.000000
#    43.                    "DifferenceEntropy"  7.000000
#    44.   "GrayLevelNonUniformityNormalized.1"  7.000000
#    45.                   "MaximumProbability"  7.000000
#    46.                "SizeZoneNonUniformity"  7.000000
#    47.        "SmallAreaLowGrayLevelEmphasis"  7.000000
#    48.                         "JointAverage"  6.000000
#    49.                      "LongRunEmphasis"  6.000000
#    50.                             "Strength"  6.000000
#    51.                          "ZoneEntropy"  6.000000
#    52.                   "DependenceVariance"  5.000000
#    53.                                   "Id"  5.000000
#    54.                                 "Imc2"  5.000000
#    55.              "LowGrayLevelRunEmphasis"  5.000000
#    56.                      "RootMeanSquared"  5.000000
#    57.         "ShortRunLowGrayLevelEmphasis"  5.000000
#    58.                          "TotalEnergy"  5.000000
#    59.                               "Energy"  4.000000
#    60.               "GrayLevelNonUniformity"  4.000000
#    61.             "HighGrayLevelRunEmphasis"  4.000000
#    62.                   "InterquartileRange"  4.000000
#    63.                         "JointEntropy"  4.000000
#    64.                        "RunPercentage"  4.000000
#    65.              "SmallDependenceEmphasis"  4.000000
#    66.                           "Uniformity"  4.000000
#    67.                      "ClusterTendency"  3.000000
#    68.    "DependenceNonUniformityNormalized"  3.000000
#    69.     "GrayLevelNonUniformityNormalized"  3.000000
#    70.                                  "Idm"  3.000000
#    71.                          "RunVariance"  3.000000
#    72.                    "SmallAreaEmphasis"  3.000000
#    73.                           "SumAverage"  3.000000
#    74.                           "SumEntropy"  3.000000
#    75.                           "SumSquares"  3.000000
#    76.                       "ZonePercentage"  3.000000
#    77.              "DependenceNonUniformity"  2.000000
#    78.                              "Entropy"  2.000000
#    79.                    "GrayLevelVariance"  2.000000
#    80.                  "GrayLevelVariance.1"  2.000000
#    81.                "HighGrayLevelEmphasis"  2.000000
#    82.              "LargeDependenceEmphasis"  2.000000
#    83.                 "LowGrayLevelEmphasis"  2.000000
#    84.                           "RunEntropy"  2.000000
#    85.               "RunLengthNonUniformity"  2.000000
#    86.             "GrayLevelNonUniformity.1"  1.000000
#    87.                "MeanAbsoluteDeviation"  1.000000
#    88.     "RunLengthNonUniformityNormalized"  1.000000
#    89.                             "Variance"  1.000000
#    90.                         "ZoneVariance"  1.000000
#
# Variable Importance: SUM_SCORE:
#     1.         "LongRunHighGrayLevelEmphasis" 8932.900581 ################
#     2. "LargeDependenceHighGrayLevelEmphasis" 1586.161707 ##
#     3.                                  "Idn" 1152.449450 ##
#     4.                             "Busyness" 562.250363 #
#     5.             "GrayLevelNonUniformity.2" 457.251131
#     6.                         "90Percentile" 429.671799
#     7.                           "Coarseness" 378.943549
#     8.                              "Maximum" 232.065377
#     9.       "LargeAreaHighGrayLevelEmphasis" 229.907760
#    10.                             "Skewness" 201.706627
#    11.       "SmallAreaHighGrayLevelEmphasis" 175.376890
#    12.                                 "Idmn" 174.177878
#    13.                           "Contrast.1" 130.088489
#    14.                               "Median" 127.424772
#    15.  "LargeDependenceLowGrayLevelEmphasis" 109.316968
#    16.                         "ClusterShade" 80.181419
#    17.  "SmallDependenceLowGrayLevelEmphasis" 73.828066
#    18.              "SmallDependenceEmphasis" 63.198073
#    19.                "SizeZoneNonUniformity" 56.727306
#    20.                          "JointEnergy" 46.028610
#    21.            "HighGrayLevelZoneEmphasis" 43.613573
#    22.                      "InverseVariance" 42.578143
#    23.                    "DifferenceAverage" 39.403173
#    24.                    "DependenceEntropy" 38.664179
#    25.                      "RootMeanSquared" 38.616473
#    26.                          "TotalEnergy" 37.786740
#    27.                "HighGrayLevelEmphasis" 36.946285
#    28.      "SizeZoneNonUniformityNormalized" 36.169374
#    29.                                 "Mean" 35.492724
#    30.                         "10Percentile" 35.166586
#    31.                   "DifferenceVariance" 33.879185
#    32.                             "Contrast" 33.504423
#    33.                           "Complexity" 32.690129
#    34. "SmallDependenceHighGrayLevelEmphasis" 29.522450
#    35.        "ShortRunHighGrayLevelEmphasis" 28.674341
#    36.                       "ZonePercentage" 25.286973
#    37.                    "DifferenceEntropy" 24.169027
#    38.                   "MaximumProbability" 22.233943
#    39.                      "Autocorrelation" 20.672994
#    40.                           "Uniformity" 20.528436
#    41.        "LargeAreaLowGrayLevelEmphasis" 19.485113
#    42.          "LongRunLowGrayLevelEmphasis" 18.587177
#    43.                                "Range" 17.729532
#    44.                             "Kurtosis" 16.708749
#    45.                              "Minimum" 15.820364
#    46.   "GrayLevelNonUniformityNormalized.1" 15.543092
#    47.                           "RunEntropy" 15.183281
#    48.                          "Correlation" 14.627087
#    49.                         "JointEntropy" 13.991434
#    50.                                  "MCC" 13.823547
#    51.         "ShortRunLowGrayLevelEmphasis" 13.610604
#    52.                             "Strength" 12.783074
#    53.              "LowGrayLevelRunEmphasis" 12.682618
#    54.             "LowGrayLevelZoneEmphasis" 11.755128
#    55.                  "GrayLevelVariance.2" 11.629227
#    56.        "SmallAreaLowGrayLevelEmphasis" 10.730714
#    57.                          "ZoneEntropy" 10.280577
#    58.                      "LongRunEmphasis"  9.258888
#    59.                              "Entropy"  8.278924
#    60.                 "LowGrayLevelEmphasis"  8.258460
#    61.                        "RunPercentage"  8.027440
#    62.                                 "Imc1"  7.475577
#    63.                                   "Id"  7.463556
#    64.                           "SumAverage"  7.286484
#    65.                   "DependenceVariance"  6.980031
#    66.                           "SumSquares"  6.449465
#    67.                         "JointAverage"  5.958836
#    68.                    "GrayLevelVariance"  5.901403
#    69.              "LargeDependenceEmphasis"  5.403394
#    70.                         "ZoneVariance"  4.663429
#    71.                                 "Imc2"  4.607473
#    72.               "GrayLevelNonUniformity"  4.548332
#    73.             "HighGrayLevelRunEmphasis"  4.502108
#    74.                    "ClusterProminence"  4.299849
#    75.    "DependenceNonUniformityNormalized"  3.657960
#    76.                               "Energy"  3.638791
#    77.                           "SumEntropy"  3.345505
#    78.     "GrayLevelNonUniformityNormalized"  3.024394
#    79.                      "ClusterTendency"  2.977801
#    80.                                  "Idm"  2.925038
#    81.                          "RunVariance"  2.828865
#    82.                             "Variance"  2.459584
#    83.                    "SmallAreaEmphasis"  2.379678
#    84.             "GrayLevelNonUniformity.1"  1.427400
#    85.                  "GrayLevelVariance.1"  1.424027
#    86.               "RunLengthNonUniformity"  1.323963
#    87.              "DependenceNonUniformity"  0.998464
#    88.                   "InterquartileRange"  0.876071
#    89.                "MeanAbsoluteDeviation"  0.667239
#    90.     "RunLengthNonUniformityNormalized"  0.140897
#
#
#
# Loss: BINOMIAL_LOG_LIKELIHOOD
# Validation loss value: 0.351219
# Number of trees per iteration: 1
# Node format: NOT_SET
# Number of trees: 52
# Total number of nodes: 2944
#
# Number of nodes by tree:
# Count: 52 Average: 56.6154 StdDev: 5.26291
# Min: 43 Max: 63 Ignored: 0
# ----------------------------------------------
# [ 43, 44)  2   3.85%   3.85% ##
# [ 44, 45)  0   0.00%   3.85%
# [ 45, 46)  0   0.00%   3.85%
# [ 46, 47)  0   0.00%   3.85%
# [ 47, 48)  2   3.85%   7.69% ##
# [ 48, 49)  0   0.00%   7.69%
# [ 49, 50)  4   7.69%  15.38% ###
# [ 50, 51)  0   0.00%  15.38%
# [ 51, 52)  4   7.69%  23.08% ###
# [ 52, 53)  0   0.00%  23.08%
# [ 53, 54)  2   3.85%  26.92% ##
# [ 54, 55)  0   0.00%  26.92%
# [ 55, 56)  3   5.77%  32.69% ###
# [ 56, 57)  0   0.00%  32.69%
# [ 57, 58)  8  15.38%  48.08% #######
# [ 58, 59)  0   0.00%  48.08%
# [ 59, 60) 10  19.23%  67.31% ########
# [ 60, 61)  0   0.00%  67.31%
# [ 61, 62) 12  23.08%  90.38% ##########
# [ 62, 63]  5   9.62% 100.00% ####
#
# Depth by leafs:
# Count: 1498 Average: 4.90521 StdDev: 0.341343
# Min: 2 Max: 5 Ignored: 0
# ----------------------------------------------
# [ 2, 3)    1   0.07%   0.07%
# [ 3, 4)   20   1.34%   1.40%
# [ 4, 5)   99   6.61%   8.01% #
# [ 5, 5] 1378  91.99% 100.00% ##########
#
# Number of training obs by leaf:
# Count: 1498 Average: 435.335 StdDev: 1208.45
# Min: 5 Max: 10743 Ignored: 0
# ----------------------------------------------
# [     5,   541) 1290  86.11%  86.11% ##########
# [   541,  1078)   72   4.81%  90.92% #
# [  1078,  1615)   26   1.74%  92.66%
# [  1615,  2152)   21   1.40%  94.06%
# [  2152,  2689)   14   0.93%  94.99%
# [  2689,  3226)    8   0.53%  95.53%
# [  3226,  3763)   10   0.67%  96.19%
# [  3763,  4300)    7   0.47%  96.66%
# [  4300,  4837)   10   0.67%  97.33%
# [  4837,  5374)    8   0.53%  97.86%
# [  5374,  5911)   12   0.80%  98.66%
# [  5911,  6448)    3   0.20%  98.87%
# [  6448,  6985)    8   0.53%  99.40%
# [  6985,  7522)    3   0.20%  99.60%
# [  7522,  8059)    1   0.07%  99.67%
# [  8059,  8596)    1   0.07%  99.73%
# [  8596,  9133)    2   0.13%  99.87%
# [  9133,  9670)    1   0.07%  99.93%
# [  9670, 10207)    0   0.00%  99.93%
# [ 10207, 10743]    1   0.07% 100.00%
#
# Attribute in nodes:
# 	167 : Idn [NUMERICAL]
# 	105 : LargeDependenceHighGrayLevelEmphasis [NUMERICAL]
# 	80 : Coarseness [NUMERICAL]
# 	71 : LongRunHighGrayLevelEmphasis [NUMERICAL]
# 	61 : Busyness [NUMERICAL]
# 	55 : Skewness [NUMERICAL]
# 	51 : Maximum [NUMERICAL]
# 	51 : GrayLevelNonUniformity.2 [NUMERICAL]
# 	50 : LargeAreaHighGrayLevelEmphasis [NUMERICAL]
# 	47 : Idmn [NUMERICAL]
# 	45 : 90Percentile [NUMERICAL]
# 	43 : ClusterShade [NUMERICAL]
# 	33 : Median [NUMERICAL]
# 	31 : SmallAreaHighGrayLevelEmphasis [NUMERICAL]
# 	29 : SmallDependenceLowGrayLevelEmphasis [NUMERICAL]
# 	29 : LargeDependenceLowGrayLevelEmphasis [NUMERICAL]
# 	23 : SmallDependenceHighGrayLevelEmphasis [NUMERICAL]
# 	23 : DependenceEntropy [NUMERICAL]
# 	19 : Contrast.1 [NUMERICAL]
# 	18 : InverseVariance [NUMERICAL]
# 	16 : Kurtosis [NUMERICAL]
# 	16 : HighGrayLevelZoneEmphasis [NUMERICAL]
# 	16 : 10Percentile [NUMERICAL]
# 	15 : DifferenceVariance [NUMERICAL]
# 	12 : SizeZoneNonUniformityNormalized [NUMERICAL]
# 	12 : Contrast [NUMERICAL]
# 	11 : MCC [NUMERICAL]
# 	11 : GrayLevelVariance.2 [NUMERICAL]
# 	11 : Complexity [NUMERICAL]
# 	10 : ShortRunHighGrayLevelEmphasis [NUMERICAL]
# 	10 : LowGrayLevelZoneEmphasis [NUMERICAL]
# 	10 : Correlation [NUMERICAL]
# 	10 : Autocorrelation [NUMERICAL]
# 	9 : Range [NUMERICAL]
# 	9 : Minimum [NUMERICAL]
# 	9 : LargeAreaLowGrayLevelEmphasis [NUMERICAL]
# 	9 : Imc1 [NUMERICAL]
# 	9 : ClusterProminence [NUMERICAL]
# 	8 : Mean [NUMERICAL]
# 	8 : LongRunLowGrayLevelEmphasis [NUMERICAL]
# 	8 : JointEnergy [NUMERICAL]
# 	7 : SmallAreaLowGrayLevelEmphasis [NUMERICAL]
# 	7 : SizeZoneNonUniformity [NUMERICAL]
# 	7 : MaximumProbability [NUMERICAL]
# 	7 : GrayLevelNonUniformityNormalized.1 [NUMERICAL]
# 	7 : DifferenceEntropy [NUMERICAL]
# 	7 : DifferenceAverage [NUMERICAL]
# 	6 : ZoneEntropy [NUMERICAL]
# 	6 : Strength [NUMERICAL]
# 	6 : LongRunEmphasis [NUMERICAL]
# 	6 : JointAverage [NUMERICAL]
# 	5 : TotalEnergy [NUMERICAL]
# 	5 : ShortRunLowGrayLevelEmphasis [NUMERICAL]
# 	5 : RootMeanSquared [NUMERICAL]
# 	5 : LowGrayLevelRunEmphasis [NUMERICAL]
# 	5 : Imc2 [NUMERICAL]
# 	5 : Id [NUMERICAL]
# 	5 : DependenceVariance [NUMERICAL]
# 	4 : Uniformity [NUMERICAL]
# 	4 : SmallDependenceEmphasis [NUMERICAL]
# 	4 : RunPercentage [NUMERICAL]
# 	4 : JointEntropy [NUMERICAL]
# 	4 : InterquartileRange [NUMERICAL]
# 	4 : HighGrayLevelRunEmphasis [NUMERICAL]
# 	4 : GrayLevelNonUniformity [NUMERICAL]
# 	4 : Energy [NUMERICAL]
# 	3 : ZonePercentage [NUMERICAL]
# 	3 : SumSquares [NUMERICAL]
# 	3 : SumEntropy [NUMERICAL]
# 	3 : SumAverage [NUMERICAL]
# 	3 : SmallAreaEmphasis [NUMERICAL]
# 	3 : RunVariance [NUMERICAL]
# 	3 : Idm [NUMERICAL]
# 	3 : GrayLevelNonUniformityNormalized [NUMERICAL]
# 	3 : DependenceNonUniformityNormalized [NUMERICAL]
# 	3 : ClusterTendency [NUMERICAL]
# 	2 : RunLengthNonUniformity [NUMERICAL]
# 	2 : RunEntropy [NUMERICAL]
# 	2 : LowGrayLevelEmphasis [NUMERICAL]
# 	2 : LargeDependenceEmphasis [NUMERICAL]
# 	2 : HighGrayLevelEmphasis [NUMERICAL]
# 	2 : GrayLevelVariance.1 [NUMERICAL]
# 	2 : GrayLevelVariance [NUMERICAL]
# 	2 : Entropy [NUMERICAL]
# 	2 : DependenceNonUniformity [NUMERICAL]
# 	1 : ZoneVariance [NUMERICAL]
# 	1 : Variance [NUMERICAL]
# 	1 : RunLengthNonUniformityNormalized [NUMERICAL]
# 	1 : MeanAbsoluteDeviation [NUMERICAL]
# 	1 : GrayLevelNonUniformity.1 [NUMERICAL]
#
# Attribute in nodes with depth <= 0:
# 	22 : LongRunHighGrayLevelEmphasis [NUMERICAL]
# 	14 : LargeDependenceHighGrayLevelEmphasis [NUMERICAL]
# 	8 : Busyness [NUMERICAL]
# 	3 : Maximum [NUMERICAL]
# 	3 : Coarseness [NUMERICAL]
# 	1 : TotalEnergy [NUMERICAL]
# 	1 : HighGrayLevelEmphasis [NUMERICAL]
#
# Attribute in nodes with depth <= 1:
# 	34 : LongRunHighGrayLevelEmphasis [NUMERICAL]
# 	33 : LargeDependenceHighGrayLevelEmphasis [NUMERICAL]
# 	17 : Idn [NUMERICAL]
# 	11 : Coarseness [NUMERICAL]
# 	11 : Busyness [NUMERICAL]
# 	9 : Maximum [NUMERICAL]
# 	7 : Skewness [NUMERICAL]
# 	6 : ClusterShade [NUMERICAL]
# 	4 : SmallDependenceLowGrayLevelEmphasis [NUMERICAL]
# 	4 : 90Percentile [NUMERICAL]
# 	3 : SmallAreaEmphasis [NUMERICAL]
# 	3 : Median [NUMERICAL]
# 	3 : LargeAreaHighGrayLevelEmphasis [NUMERICAL]
# 	2 : Idmn [NUMERICAL]
# 	2 : HighGrayLevelRunEmphasis [NUMERICAL]
# 	1 : TotalEnergy [NUMERICAL]
# 	1 : SmallDependenceHighGrayLevelEmphasis [NUMERICAL]
# 	1 : LowGrayLevelEmphasis [NUMERICAL]
# 	1 : InverseVariance [NUMERICAL]
# 	1 : HighGrayLevelEmphasis [NUMERICAL]
# 	1 : GrayLevelNonUniformity.2 [NUMERICAL]
# 	1 : DependenceNonUniformityNormalized [NUMERICAL]
#
# Attribute in nodes with depth <= 2:
# 	47 : Idn [NUMERICAL]
# 	45 : LargeDependenceHighGrayLevelEmphasis [NUMERICAL]
# 	37 : LongRunHighGrayLevelEmphasis [NUMERICAL]
# 	30 : Busyness [NUMERICAL]
# 	22 : Coarseness [NUMERICAL]
# 	17 : Maximum [NUMERICAL]
# 	16 : GrayLevelNonUniformity.2 [NUMERICAL]
# 	15 : Skewness [NUMERICAL]
# 	14 : ClusterShade [NUMERICAL]
# 	11 : LargeAreaHighGrayLevelEmphasis [NUMERICAL]
# 	10 : SmallAreaHighGrayLevelEmphasis [NUMERICAL]
# 	8 : SmallDependenceLowGrayLevelEmphasis [NUMERICAL]
# 	8 : Median [NUMERICAL]
# 	8 : 90Percentile [NUMERICAL]
# 	6 : SmallDependenceHighGrayLevelEmphasis [NUMERICAL]
# 	6 : Idmn [NUMERICAL]
# 	5 : DependenceEntropy [NUMERICAL]
# 	3 : SumAverage [NUMERICAL]
# 	3 : SmallAreaEmphasis [NUMERICAL]
# 	3 : InverseVariance [NUMERICAL]
# 	3 : HighGrayLevelZoneEmphasis [NUMERICAL]
# 	3 : GrayLevelVariance.2 [NUMERICAL]
# 	2 : SizeZoneNonUniformityNormalized [NUMERICAL]
# 	2 : ShortRunHighGrayLevelEmphasis [NUMERICAL]
# 	2 : RunEntropy [NUMERICAL]
# 	2 : Mean [NUMERICAL]
# 	2 : MCC [NUMERICAL]
# 	2 : LowGrayLevelEmphasis [NUMERICAL]
# 	2 : Kurtosis [NUMERICAL]
# 	2 : Imc2 [NUMERICAL]
# 	2 : HighGrayLevelRunEmphasis [NUMERICAL]
# 	2 : DifferenceVariance [NUMERICAL]
# 	1 : ZoneVariance [NUMERICAL]
# 	1 : ZoneEntropy [NUMERICAL]
# 	1 : Uniformity [NUMERICAL]
# 	1 : TotalEnergy [NUMERICAL]
# 	1 : Strength [NUMERICAL]
# 	1 : SizeZoneNonUniformity [NUMERICAL]
# 	1 : RootMeanSquared [NUMERICAL]
# 	1 : Range [NUMERICAL]
# 	1 : Minimum [NUMERICAL]
# 	1 : MaximumProbability [NUMERICAL]
# 	1 : LowGrayLevelZoneEmphasis [NUMERICAL]
# 	1 : LongRunEmphasis [NUMERICAL]
# 	1 : JointEnergy [NUMERICAL]
# 	1 : JointAverage [NUMERICAL]
# 	1 : Imc1 [NUMERICAL]
# 	1 : Id [NUMERICAL]
# 	1 : HighGrayLevelEmphasis [NUMERICAL]
# 	1 : GrayLevelNonUniformityNormalized.1 [NUMERICAL]
# 	1 : DependenceNonUniformityNormalized [NUMERICAL]
# 	1 : Contrast.1 [NUMERICAL]
# 	1 : Contrast [NUMERICAL]
# 	1 : Autocorrelation [NUMERICAL]
# 	1 : 10Percentile [NUMERICAL]
#
# Attribute in nodes with depth <= 3:
# 	92 : Idn [NUMERICAL]
# 	66 : LargeDependenceHighGrayLevelEmphasis [NUMERICAL]
# 	48 : LongRunHighGrayLevelEmphasis [NUMERICAL]
# 	42 : Coarseness [NUMERICAL]
# 	40 : GrayLevelNonUniformity.2 [NUMERICAL]
# 	40 : Busyness [NUMERICAL]
# 	29 : Maximum [NUMERICAL]
# 	29 : LargeAreaHighGrayLevelEmphasis [NUMERICAL]
# 	26 : Skewness [NUMERICAL]
# 	23 : Idmn [NUMERICAL]
# 	23 : ClusterShade [NUMERICAL]
# 	20 : 90Percentile [NUMERICAL]
# 	17 : SmallAreaHighGrayLevelEmphasis [NUMERICAL]
# 	16 : Median [NUMERICAL]
# 	15 : InverseVariance [NUMERICAL]
# 	14 : SmallDependenceLowGrayLevelEmphasis [NUMERICAL]
# 	13 : SmallDependenceHighGrayLevelEmphasis [NUMERICAL]
# 	9 : HighGrayLevelZoneEmphasis [NUMERICAL]
# 	9 : DependenceEntropy [NUMERICAL]
# 	8 : Kurtosis [NUMERICAL]
# 	7 : SizeZoneNonUniformityNormalized [NUMERICAL]
# 	7 : LargeDependenceLowGrayLevelEmphasis [NUMERICAL]
# 	7 : Contrast.1 [NUMERICAL]
# 	6 : SizeZoneNonUniformity [NUMERICAL]
# 	6 : MCC [NUMERICAL]
# 	6 : DifferenceVariance [NUMERICAL]
# 	5 : ShortRunHighGrayLevelEmphasis [NUMERICAL]
# 	5 : LongRunEmphasis [NUMERICAL]
# 	5 : GrayLevelVariance.2 [NUMERICAL]
# 	5 : Contrast [NUMERICAL]
# 	5 : Autocorrelation [NUMERICAL]
# 	5 : 10Percentile [NUMERICAL]
# 	4 : JointEnergy [NUMERICAL]
# 	4 : Complexity [NUMERICAL]
# 	4 : ClusterProminence [NUMERICAL]
# 	3 : Uniformity [NUMERICAL]
# 	3 : TotalEnergy [NUMERICAL]
# 	3 : SumAverage [NUMERICAL]
# 	3 : Strength [NUMERICAL]
# 	3 : SmallDependenceEmphasis [NUMERICAL]
# 	3 : SmallAreaEmphasis [NUMERICAL]
# 	3 : RunPercentage [NUMERICAL]
# 	3 : Range [NUMERICAL]
# 	3 : Mean [NUMERICAL]
# 	3 : MaximumProbability [NUMERICAL]
# 	3 : JointAverage [NUMERICAL]
# 	3 : Imc2 [NUMERICAL]
# 	3 : Imc1 [NUMERICAL]
# 	3 : GrayLevelNonUniformityNormalized.1 [NUMERICAL]
# 	3 : DifferenceEntropy [NUMERICAL]
# 	3 : DifferenceAverage [NUMERICAL]
# 	3 : DependenceNonUniformityNormalized [NUMERICAL]
# 	3 : Correlation [NUMERICAL]
# 	2 : ZonePercentage [NUMERICAL]
# 	2 : ZoneEntropy [NUMERICAL]
# 	2 : SumSquares [NUMERICAL]
# 	2 : RunVariance [NUMERICAL]
# 	2 : RunEntropy [NUMERICAL]
# 	2 : Minimum [NUMERICAL]
# 	2 : LowGrayLevelZoneEmphasis [NUMERICAL]
# 	2 : LowGrayLevelEmphasis [NUMERICAL]
# 	2 : LongRunLowGrayLevelEmphasis [NUMERICAL]
# 	2 : LargeAreaLowGrayLevelEmphasis [NUMERICAL]
# 	2 : HighGrayLevelRunEmphasis [NUMERICAL]
# 	2 : GrayLevelNonUniformityNormalized [NUMERICAL]
# 	2 : GrayLevelNonUniformity [NUMERICAL]
# 	1 : ZoneVariance [NUMERICAL]
# 	1 : Variance [NUMERICAL]
# 	1 : SumEntropy [NUMERICAL]
# 	1 : SmallAreaLowGrayLevelEmphasis [NUMERICAL]
# 	1 : ShortRunLowGrayLevelEmphasis [NUMERICAL]
# 	1 : RunLengthNonUniformityNormalized [NUMERICAL]
# 	1 : RunLengthNonUniformity [NUMERICAL]
# 	1 : RootMeanSquared [NUMERICAL]
# 	1 : MeanAbsoluteDeviation [NUMERICAL]
# 	1 : LowGrayLevelRunEmphasis [NUMERICAL]
# 	1 : LargeDependenceEmphasis [NUMERICAL]
# 	1 : JointEntropy [NUMERICAL]
# 	1 : Id [NUMERICAL]
# 	1 : HighGrayLevelEmphasis [NUMERICAL]
# 	1 : GrayLevelVariance.1 [NUMERICAL]
# 	1 : GrayLevelNonUniformity.1 [NUMERICAL]
# 	1 : ClusterTendency [NUMERICAL]
#
# Attribute in nodes with depth <= 5:
# 	167 : Idn [NUMERICAL]
# 	105 : LargeDependenceHighGrayLevelEmphasis [NUMERICAL]
# 	80 : Coarseness [NUMERICAL]
# 	71 : LongRunHighGrayLevelEmphasis [NUMERICAL]
# 	61 : Busyness [NUMERICAL]
# 	55 : Skewness [NUMERICAL]
# 	51 : Maximum [NUMERICAL]
# 	51 : GrayLevelNonUniformity.2 [NUMERICAL]
# 	50 : LargeAreaHighGrayLevelEmphasis [NUMERICAL]
# 	47 : Idmn [NUMERICAL]
# 	45 : 90Percentile [NUMERICAL]
# 	43 : ClusterShade [NUMERICAL]
# 	33 : Median [NUMERICAL]
# 	31 : SmallAreaHighGrayLevelEmphasis [NUMERICAL]
# 	29 : SmallDependenceLowGrayLevelEmphasis [NUMERICAL]
# 	29 : LargeDependenceLowGrayLevelEmphasis [NUMERICAL]
# 	23 : SmallDependenceHighGrayLevelEmphasis [NUMERICAL]
# 	23 : DependenceEntropy [NUMERICAL]
# 	19 : Contrast.1 [NUMERICAL]
# 	18 : InverseVariance [NUMERICAL]
# 	16 : Kurtosis [NUMERICAL]
# 	16 : HighGrayLevelZoneEmphasis [NUMERICAL]
# 	16 : 10Percentile [NUMERICAL]
# 	15 : DifferenceVariance [NUMERICAL]
# 	12 : SizeZoneNonUniformityNormalized [NUMERICAL]
# 	12 : Contrast [NUMERICAL]
# 	11 : MCC [NUMERICAL]
# 	11 : GrayLevelVariance.2 [NUMERICAL]
# 	11 : Complexity [NUMERICAL]
# 	10 : ShortRunHighGrayLevelEmphasis [NUMERICAL]
# 	10 : LowGrayLevelZoneEmphasis [NUMERICAL]
# 	10 : Correlation [NUMERICAL]
# 	10 : Autocorrelation [NUMERICAL]
# 	9 : Range [NUMERICAL]
# 	9 : Minimum [NUMERICAL]
# 	9 : LargeAreaLowGrayLevelEmphasis [NUMERICAL]
# 	9 : Imc1 [NUMERICAL]
# 	9 : ClusterProminence [NUMERICAL]
# 	8 : Mean [NUMERICAL]
# 	8 : LongRunLowGrayLevelEmphasis [NUMERICAL]
# 	8 : JointEnergy [NUMERICAL]
# 	7 : SmallAreaLowGrayLevelEmphasis [NUMERICAL]
# 	7 : SizeZoneNonUniformity [NUMERICAL]
# 	7 : MaximumProbability [NUMERICAL]
# 	7 : GrayLevelNonUniformityNormalized.1 [NUMERICAL]
# 	7 : DifferenceEntropy [NUMERICAL]
# 	7 : DifferenceAverage [NUMERICAL]
# 	6 : ZoneEntropy [NUMERICAL]
# 	6 : Strength [NUMERICAL]
# 	6 : LongRunEmphasis [NUMERICAL]
# 	6 : JointAverage [NUMERICAL]
# 	5 : TotalEnergy [NUMERICAL]
# 	5 : ShortRunLowGrayLevelEmphasis [NUMERICAL]
# 	5 : RootMeanSquared [NUMERICAL]
# 	5 : LowGrayLevelRunEmphasis [NUMERICAL]
# 	5 : Imc2 [NUMERICAL]
# 	5 : Id [NUMERICAL]
# 	5 : DependenceVariance [NUMERICAL]
# 	4 : Uniformity [NUMERICAL]
# 	4 : SmallDependenceEmphasis [NUMERICAL]
# 	4 : RunPercentage [NUMERICAL]
# 	4 : JointEntropy [NUMERICAL]
# 	4 : InterquartileRange [NUMERICAL]
# 	4 : HighGrayLevelRunEmphasis [NUMERICAL]
# 	4 : GrayLevelNonUniformity [NUMERICAL]
# 	4 : Energy [NUMERICAL]
# 	3 : ZonePercentage [NUMERICAL]
# 	3 : SumSquares [NUMERICAL]
# 	3 : SumEntropy [NUMERICAL]
# 	3 : SumAverage [NUMERICAL]
# 	3 : SmallAreaEmphasis [NUMERICAL]
# 	3 : RunVariance [NUMERICAL]
# 	3 : Idm [NUMERICAL]
# 	3 : GrayLevelNonUniformityNormalized [NUMERICAL]
# 	3 : DependenceNonUniformityNormalized [NUMERICAL]
# 	3 : ClusterTendency [NUMERICAL]
# 	2 : RunLengthNonUniformity [NUMERICAL]
# 	2 : RunEntropy [NUMERICAL]
# 	2 : LowGrayLevelEmphasis [NUMERICAL]
# 	2 : LargeDependenceEmphasis [NUMERICAL]
# 	2 : HighGrayLevelEmphasis [NUMERICAL]
# 	2 : GrayLevelVariance.1 [NUMERICAL]
# 	2 : GrayLevelVariance [NUMERICAL]
# 	2 : Entropy [NUMERICAL]
# 	2 : DependenceNonUniformity [NUMERICAL]
# 	1 : ZoneVariance [NUMERICAL]
# 	1 : Variance [NUMERICAL]
# 	1 : RunLengthNonUniformityNormalized [NUMERICAL]
# 	1 : MeanAbsoluteDeviation [NUMERICAL]
# 	1 : GrayLevelNonUniformity.1 [NUMERICAL]
#
# Condition type in nodes:
# 	1446 : HigherCondition
# Condition type in nodes with depth <= 0:
# 	52 : HigherCondition
# Condition type in nodes with depth <= 1:
# 	156 : HigherCondition
# Condition type in nodes with depth <= 2:
# 	363 : HigherCondition
# Condition type in nodes with depth <= 3:
# 	757 : HigherCondition
# Condition type in nodes with depth <= 5:
# 	1446 : HigherCondition
#
# Training logs:
# Number of iteration to final model: 52
# 	Iter:1 train-loss:1.236870 valid-loss:1.252327  train-accuracy:0.930249 valid-accuracy:0.890223
# 	Iter:2 train-loss:1.112448 valid-loss:1.142808  train-accuracy:0.939453 valid-accuracy:0.894440
# 	Iter:3 train-loss:1.004545 valid-loss:1.046873  train-accuracy:0.951099 valid-accuracy:0.899047
# 	Iter:4 train-loss:0.913799 valid-loss:0.965925  train-accuracy:0.955516 valid-accuracy:0.896257
# 	Iter:5 train-loss:0.838264 valid-loss:0.899870  train-accuracy:0.943643 valid-accuracy:0.896646
# 	Iter:6 train-loss:0.770365 valid-loss:0.843590  train-accuracy:0.946214 valid-accuracy:0.893856
# 	Iter:16 train-loss:0.389812 valid-loss:0.530088  train-accuracy:0.970195 valid-accuracy:0.913126
# 	Iter:26 train-loss:0.240923 valid-loss:0.423826  train-accuracy:0.980805 valid-accuracy:0.920976
# 	Iter:36 train-loss:0.165004 valid-loss:0.378606  train-accuracy:0.987551 valid-accuracy:0.927270
# 	Iter:46 train-loss:0.119196 valid-loss:0.356863  train-accuracy:0.991450 valid-accuracy:0.922144
# 	Iter:56 train-loss:0.093742 valid-loss:0.356118  train-accuracy:0.993722 valid-accuracy:0.933563
# 	Iter:66 train-loss:0.074360 valid-loss:0.362014  train-accuracy:0.995995 valid-accuracy:0.933952
# 	Iter:76 train-loss:0.060720 valid-loss:0.378333  train-accuracy:0.996975 valid-accuracy:0.934731

# %%
# Model features
model.make_inspector().features()
# Out:
# ["10Percentile" (1; #0),
#  "90Percentile" (1; #1),
#  "Autocorrelation" (1; #2),
#  "Busyness" (1; #3),
#  "ClusterProminence" (1; #4),
#  "ClusterShade" (1; #5),
#  "ClusterTendency" (1; #6),
#  "Coarseness" (1; #7),
#  "Complexity" (1; #8),
#  "Contrast" (1; #9),
#  "Contrast.1" (1; #10),
#  "Correlation" (1; #11),
#  "DependenceEntropy" (1; #12),
#  "DependenceNonUniformity" (1; #13),
#  "DependenceNonUniformityNormalized" (1; #14),
#  "DependenceVariance" (1; #15),
#  "DifferenceAverage" (1; #16),
#  "DifferenceEntropy" (1; #17),
#  "DifferenceVariance" (1; #18),
#  "Energy" (1; #19),
#  "Entropy" (1; #20),
#  "GrayLevelNonUniformity" (1; #21),
#  "GrayLevelNonUniformity.1" (1; #22),
#  "GrayLevelNonUniformity.2" (1; #23),
#  "GrayLevelNonUniformityNormalized" (1; #24),
#  "GrayLevelNonUniformityNormalized.1" (1; #25),
#  "GrayLevelVariance" (1; #26),
#  "GrayLevelVariance.1" (1; #27),
#  "GrayLevelVariance.2" (1; #28),
#  "HighGrayLevelEmphasis" (1; #29),
#  "HighGrayLevelRunEmphasis" (1; #30),
#  "HighGrayLevelZoneEmphasis" (1; #31),
#  "Id" (1; #32),
#  "Idm" (1; #33),
#  "Idmn" (1; #34),
#  "Idn" (1; #35),
#  "Imc1" (1; #36),
#  "Imc2" (1; #37),
#  "InterquartileRange" (1; #38),
#  "InverseVariance" (1; #39),
#  "JointAverage" (1; #40),
#  "JointEnergy" (1; #41),
#  "JointEntropy" (1; #42),
#  "Kurtosis" (1; #43),
#  "LargeAreaEmphasis" (1; #44),
#  "LargeAreaHighGrayLevelEmphasis" (1; #45),
#  "LargeAreaLowGrayLevelEmphasis" (1; #46),
#  "LargeDependenceEmphasis" (1; #47),
#  "LargeDependenceHighGrayLevelEmphasis" (1; #48),
#  "LargeDependenceLowGrayLevelEmphasis" (1; #49),
#  "LongRunEmphasis" (1; #50),
#  "LongRunHighGrayLevelEmphasis" (1; #51),
#  "LongRunLowGrayLevelEmphasis" (1; #52),
#  "LowGrayLevelEmphasis" (1; #53),
#  "LowGrayLevelRunEmphasis" (1; #54),
#  "LowGrayLevelZoneEmphasis" (1; #55),
#  "MCC" (1; #56),
#  "Maximum" (1; #57),
#  "MaximumProbability" (1; #58),
#  "Mean" (1; #59),
#  "MeanAbsoluteDeviation" (1; #60),
#  "Median" (1; #61),
#  "Minimum" (1; #62),
#  "Range" (1; #63),
#  "RobustMeanAbsoluteDeviation" (1; #64),
#  "RootMeanSquared" (1; #65),
#  "RunEntropy" (1; #66),
#  "RunLengthNonUniformity" (1; #67),
#  "RunLengthNonUniformityNormalized" (1; #68),
#  "RunPercentage" (1; #69),
#  "RunVariance" (1; #70),
#  "ShortRunEmphasis" (1; #71),
#  "ShortRunHighGrayLevelEmphasis" (1; #72),
#  "ShortRunLowGrayLevelEmphasis" (1; #73),
#  "SizeZoneNonUniformity" (1; #74),
#  "SizeZoneNonUniformityNormalized" (1; #75),
#  "Skewness" (1; #76),
#  "SmallAreaEmphasis" (1; #77),
#  "SmallAreaHighGrayLevelEmphasis" (1; #78),
#  "SmallAreaLowGrayLevelEmphasis" (1; #79),
#  "SmallDependenceEmphasis" (1; #80),
#  "SmallDependenceHighGrayLevelEmphasis" (1; #81),
#  "SmallDependenceLowGrayLevelEmphasis" (1; #82),
#  "Strength" (1; #83),
#  "SumAverage" (1; #84),
#  "SumEntropy" (1; #85),
#  "SumSquares" (1; #86),
#  "TotalEnergy" (1; #87),
#  "Uniformity" (1; #88),
#  "Variance" (1; #89),
#  "ZoneEntropy" (1; #90),
#  "ZonePercentage" (1; #91),
#  "ZoneVariance" (1; #92)]

# %%
# Feature importance
model.make_inspector().variable_importances()
# Out:
# {'INV_MEAN_MIN_DEPTH': [("LargeDependenceHighGrayLevelEmphasis" (1; #48),
#    0.2761945696572916),
#   ("LongRunHighGrayLevelEmphasis" (1; #51), 0.26408195677614515),
#   ("Idn" (1; #35), 0.22065974767029617),
#   ("Busyness" (1; #3), 0.2090980873684431),
#   ("Coarseness" (1; #7), 0.20078318283680616),
#   ("Maximum" (1; #57), 0.1932537115525057),
#   ("Skewness" (1; #76), 0.18281404903888934),
#   ("GrayLevelNonUniformity.2" (1; #23), 0.18146626977394317),
#   ("LargeAreaHighGrayLevelEmphasis" (1; #45), 0.1800587358432743),
#   ("ClusterShade" (1; #5), 0.1793962602150647),
#   ("90Percentile" (1; #1), 0.17843970890466415),
#   ("SmallDependenceLowGrayLevelEmphasis" (1; #82), 0.17725492364733217),
#   ("Idmn" (1; #34), 0.17669841415640858),
#   ("Median" (1; #61), 0.17646734940207306),
#   ("SmallAreaHighGrayLevelEmphasis" (1; #78), 0.17549437901784393),
#   ("SmallDependenceHighGrayLevelEmphasis" (1; #81), 0.17423116897669508),
#   ("InverseVariance" (1; #39), 0.17319978920586426),
#   ("SmallAreaEmphasis" (1; #77), 0.17302573599188634),
#   ("TotalEnergy" (1; #87), 0.17266307892804375),
#   ("HighGrayLevelEmphasis" (1; #29), 0.17239328241519006),
#   ("DependenceEntropy" (1; #12), 0.17219342946828503),
#   ("HighGrayLevelRunEmphasis" (1; #30), 0.17169525419444848),
#   ("HighGrayLevelZoneEmphasis" (1; #31), 0.1716667865443158),
#   ("LargeDependenceLowGrayLevelEmphasis" (1; #49), 0.17136059637946985),
#   ("Contrast.1" (1; #10), 0.17129235937697349),
#   ("GrayLevelVariance.2" (1; #28), 0.17122694959251525),
#   ("Kurtosis" (1; #43), 0.17118863072652016),
#   ("SizeZoneNonUniformityNormalized" (1; #75), 0.17117997290306555),
#   ("DifferenceVariance" (1; #18), 0.17105866830217412),
#   ("10Percentile" (1; #0), 0.17101607232407465),
#   ("LowGrayLevelEmphasis" (1; #53), 0.17100559089918768),
#   ("ShortRunHighGrayLevelEmphasis" (1; #72), 0.1709380336279128),
#   ("DependenceNonUniformityNormalized" (1; #14), 0.17080553125011297),
#   ("SumAverage" (1; #84), 0.17078691187464026),
#   ("Contrast" (1; #9), 0.17075020061889554),
#   ("LongRunEmphasis" (1; #50), 0.17073324869468573),
#   ("SizeZoneNonUniformity" (1; #74), 0.1707251050228251),
#   ("Mean" (1; #59), 0.17062028488468817),
#   ("Imc2" (1; #37), 0.17060309211995411),
#   ("MCC" (1; #56), 0.1705930088052878),
#   ("Autocorrelation" (1; #2), 0.1705418294487028),
#   ("JointEnergy" (1; #41), 0.17049500884475263),
#   ("MaximumProbability" (1; #58), 0.17048320556472116),
#   ("Range" (1; #63), 0.1704604755688417),
#   ("LowGrayLevelZoneEmphasis" (1; #55), 0.17045560636843357),
#   ("Imc1" (1; #36), 0.1704374940635339),
#   ("RunEntropy" (1; #66), 0.17037768232442488),
#   ("JointAverage" (1; #40), 0.17033831601828345),
#   ("Strength" (1; #83), 0.170332447182244),
#   ("Complexity" (1; #8), 0.1703253318632697),
#   ("GrayLevelNonUniformityNormalized.1" (1; #25), 0.17031039703661882),
#   ("Minimum" (1; #62), 0.1703056825779805),
#   ("Correlation" (1; #11), 0.17025605071790617),
#   ("ZoneEntropy" (1; #90), 0.1702377518408884),
#   ("ClusterProminence" (1; #4), 0.17022123165204703),
#   ("DifferenceEntropy" (1; #17), 0.1701676812681972),
#   ("LargeAreaLowGrayLevelEmphasis" (1; #46), 0.17011709551997173),
#   ("RootMeanSquared" (1; #65), 0.1700876142314442),
#   ("DifferenceAverage" (1; #16), 0.17006164445792007),
#   ("LongRunLowGrayLevelEmphasis" (1; #52), 0.17004178649122287),
#   ("GrayLevelNonUniformity" (1; #21), 0.1700235479600975),
#   ("SmallDependenceEmphasis" (1; #80), 0.16997285033749235),
#   ("Uniformity" (1; #88), 0.16995331177305606),
#   ("SmallAreaLowGrayLevelEmphasis" (1; #79), 0.16994906083953032),
#   ("RunPercentage" (1; #69), 0.16994633357055225),
#   ("ZoneVariance" (1; #92), 0.16992187973416747),
#   ("LowGrayLevelRunEmphasis" (1; #54), 0.16990011308041722),
#   ("ZonePercentage" (1; #91), 0.16989136921130374),
#   ("GrayLevelNonUniformityNormalized" (1; #24), 0.1698649112352871),
#   ("ShortRunLowGrayLevelEmphasis" (1; #73), 0.169843552752851),
#   ("SumSquares" (1; #86), 0.16983535124763421),
#   ("RunVariance" (1; #70), 0.16982410181922186),
#   ("JointEntropy" (1; #42), 0.1698111986885918),
#   ("SumEntropy" (1; #85), 0.16979664498196664),
#   ("DependenceVariance" (1; #15), 0.16976112163749446),
#   ("Id" (1; #32), 0.16975583773268477),
#   ("LargeDependenceEmphasis" (1; #47), 0.16974295267715425),
#   ("ClusterTendency" (1; #6), 0.16973811691517515),
#   ("RunLengthNonUniformityNormalized" (1; #68), 0.16973470360201745),
#   ("Energy" (1; #19), 0.16971467199877746),
#   ("InterquartileRange" (1; #38), 0.16970840357210973),
#   ("GrayLevelVariance.1" (1; #27), 0.16970146400932543),
#   ("Idm" (1; #33), 0.16967812618949993),
#   ("MeanAbsoluteDeviation" (1; #60), 0.16965660627667586),
#   ("Variance" (1; #89), 0.16965660627667586),
#   ("GrayLevelNonUniformity.1" (1; #22), 0.16965363038139328),
#   ("RunLengthNonUniformity" (1; #67), 0.16964383355607962),
#   ("DependenceNonUniformity" (1; #13), 0.16964264336466708),
#   ("GrayLevelVariance" (1; #26), 0.16963942961558345),
#   ("Entropy" (1; #20), 0.16963815740867522)],
#  'NUM_AS_ROOT': [("LongRunHighGrayLevelEmphasis" (1; #51), 22.0),
#   ("LargeDependenceHighGrayLevelEmphasis" (1; #48), 14.0),
#   ("Busyness" (1; #3), 8.0),
#   ("Coarseness" (1; #7), 3.0),
#   ("Maximum" (1; #57), 3.0),
#   ("HighGrayLevelEmphasis" (1; #29), 1.0),
#   ("TotalEnergy" (1; #87), 1.0)],
#  'SUM_SCORE': [("LongRunHighGrayLevelEmphasis" (1; #51), 8932.900580932246),
#   ("LargeDependenceHighGrayLevelEmphasis" (1; #48), 1586.1617067731602),
#   ("Idn" (1; #35), 1152.4494500948008),
#   ("Busyness" (1; #3), 562.2503627039689),
#   ("GrayLevelNonUniformity.2" (1; #23), 457.2511311694453),
#   ("90Percentile" (1; #1), 429.6717985833883),
#   ("Coarseness" (1; #7), 378.94354896787473),
#   ("Maximum" (1; #57), 232.0653767360548),
#   ("LargeAreaHighGrayLevelEmphasis" (1; #45), 229.90776046820736),
#   ("Skewness" (1; #76), 201.7066270003336),
#   ("SmallAreaHighGrayLevelEmphasis" (1; #78), 175.37689029465776),
#   ("Idmn" (1; #34), 174.1778782209577),
#   ("Contrast.1" (1; #10), 130.08848886233184),
#   ("Median" (1; #61), 127.42477150161955),
#   ("LargeDependenceLowGrayLevelEmphasis" (1; #49), 109.31696808566406),
#   ("ClusterShade" (1; #5), 80.18141896698917),
#   ("SmallDependenceLowGrayLevelEmphasis" (1; #82), 73.82806623719995),
#   ("SmallDependenceEmphasis" (1; #80), 63.198073294345036),
#   ("SizeZoneNonUniformity" (1; #74), 56.72730636985174),
#   ("JointEnergy" (1; #41), 46.02860953863929),
#   ("HighGrayLevelZoneEmphasis" (1; #31), 43.61357277112263),
#   ("InverseVariance" (1; #39), 42.57814323851029),
#   ("DifferenceAverage" (1; #16), 39.40317337730984),
#   ("DependenceEntropy" (1; #12), 38.664178940478884),
#   ("RootMeanSquared" (1; #65), 38.616473231077805),
#   ("TotalEnergy" (1; #87), 37.78674015248608),
#   ("HighGrayLevelEmphasis" (1; #29), 36.946285136980016),
#   ("SizeZoneNonUniformityNormalized" (1; #75), 36.16937445670087),
#   ("Mean" (1; #59), 35.49272391534426),
#   ("10Percentile" (1; #0), 35.166586230902176),
#   ("DifferenceVariance" (1; #18), 33.87918532632571),
#   ("Contrast" (1; #9), 33.50442305917924),
#   ("Complexity" (1; #8), 32.69012915126538),
#   ("SmallDependenceHighGrayLevelEmphasis" (1; #81), 29.522449893516598),
#   ("ShortRunHighGrayLevelEmphasis" (1; #72), 28.67434106208972),
#   ("ZonePercentage" (1; #91), 25.286972697288792),
#   ("DifferenceEntropy" (1; #17), 24.169027375414426),
#   ("MaximumProbability" (1; #58), 22.233942770341653),
#   ("Autocorrelation" (1; #2), 20.672994437482533),
#   ("Uniformity" (1; #88), 20.528436031458185),
#   ("LargeAreaLowGrayLevelEmphasis" (1; #46), 19.485113306858356),
#   ("LongRunLowGrayLevelEmphasis" (1; #52), 18.58717686973734),
#   ("Range" (1; #63), 17.729532077607118),
#   ("Kurtosis" (1; #43), 16.708749419422773),
#   ("Minimum" (1; #62), 15.820363996538871),
#   ("GrayLevelNonUniformityNormalized.1" (1; #25), 15.543091615153466),
#   ("RunEntropy" (1; #66), 15.18328118048214),
#   ("Correlation" (1; #11), 14.627086972217434),
#   ("JointEntropy" (1; #42), 13.991433990055887),
#   ("MCC" (1; #56), 13.823547162490392),
#   ("ShortRunLowGrayLevelEmphasis" (1; #73), 13.610603674584445),
#   ("Strength" (1; #83), 12.78307376974236),
#   ("LowGrayLevelRunEmphasis" (1; #54), 12.682618023760986),
#   ("LowGrayLevelZoneEmphasis" (1; #55), 11.755127559233582),
#   ("GrayLevelVariance.2" (1; #28), 11.629226689227815),
#   ("SmallAreaLowGrayLevelEmphasis" (1; #79), 10.730714428785898),
#   ("ZoneEntropy" (1; #90), 10.280576707405098),
#   ("LongRunEmphasis" (1; #50), 9.258888220336363),
#   ("Entropy" (1; #20), 8.27892432377465),
#   ("LowGrayLevelEmphasis" (1; #53), 8.258459839361926),
#   ("RunPercentage" (1; #69), 8.027440086715202),
#   ("Imc1" (1; #36), 7.4755770873271),
#   ("Id" (1; #32), 7.46355600679432),
#   ("SumAverage" (1; #84), 7.28648351714105),
#   ("DependenceVariance" (1; #15), 6.980031148534108),
#   ("SumSquares" (1; #86), 6.449464946617125),
#   ("JointAverage" (1; #40), 5.9588357737002875),
#   ("GrayLevelVariance" (1; #26), 5.901402886903744),
#   ("LargeDependenceEmphasis" (1; #47), 5.4033935638315755),
#   ("ZoneVariance" (1; #92), 4.663428983335078),
#   ("Imc2" (1; #37), 4.607473445815863),
#   ("GrayLevelNonUniformity" (1; #21), 4.548331802908918),
#   ("HighGrayLevelRunEmphasis" (1; #30), 4.502107754706388),
#   ("ClusterProminence" (1; #4), 4.299849005437096),
#   ("DependenceNonUniformityNormalized" (1; #14), 3.6579600321161543),
#   ("Energy" (1; #19), 3.638791195703846),
#   ("SumEntropy" (1; #85), 3.345504578455537),
#   ("GrayLevelNonUniformityNormalized" (1; #24), 3.024393961869959),
#   ("ClusterTendency" (1; #6), 2.9778014523488654),
#   ("Idm" (1; #33), 2.9250380208233726),
#   ("RunVariance" (1; #70), 2.8288650542283627),
#   ("Variance" (1; #89), 2.4595837693537073),
#   ("SmallAreaEmphasis" (1; #77), 2.379678463678798),
#   ("GrayLevelNonUniformity.1" (1; #22), 1.4273998797772518),
#   ("GrayLevelVariance.1" (1; #27), 1.4240272331302368),
#   ("RunLengthNonUniformity" (1; #67), 1.3239634447145359),
#   ("DependenceNonUniformity" (1; #13), 0.9984644408429831),
#   ("InterquartileRange" (1; #38), 0.8760709295927458),
#   ("MeanAbsoluteDeviation" (1; #60), 0.667238785222791),
#   ("RunLengthNonUniformityNormalized" (1; #68), 0.14089698756355254)],
#  'NUM_NODES': [("Idn" (1; #35), 167.0),
#   ("LargeDependenceHighGrayLevelEmphasis" (1; #48), 105.0),
#   ("Coarseness" (1; #7), 80.0),
#   ("LongRunHighGrayLevelEmphasis" (1; #51), 71.0),
#   ("Busyness" (1; #3), 61.0),
#   ("Skewness" (1; #76), 55.0),
#   ("GrayLevelNonUniformity.2" (1; #23), 51.0),
#   ("Maximum" (1; #57), 51.0),
#   ("LargeAreaHighGrayLevelEmphasis" (1; #45), 50.0),
#   ("Idmn" (1; #34), 47.0),
#   ("90Percentile" (1; #1), 45.0),
#   ("ClusterShade" (1; #5), 43.0),
#   ("Median" (1; #61), 33.0),
#   ("SmallAreaHighGrayLevelEmphasis" (1; #78), 31.0),
#   ("LargeDependenceLowGrayLevelEmphasis" (1; #49), 29.0),
#   ("SmallDependenceLowGrayLevelEmphasis" (1; #82), 29.0),
#   ("DependenceEntropy" (1; #12), 23.0),
#   ("SmallDependenceHighGrayLevelEmphasis" (1; #81), 23.0),
#   ("Contrast.1" (1; #10), 19.0),
#   ("InverseVariance" (1; #39), 18.0),
#   ("10Percentile" (1; #0), 16.0),
#   ("HighGrayLevelZoneEmphasis" (1; #31), 16.0),
#   ("Kurtosis" (1; #43), 16.0),
#   ("DifferenceVariance" (1; #18), 15.0),
#   ("Contrast" (1; #9), 12.0),
#   ("SizeZoneNonUniformityNormalized" (1; #75), 12.0),
#   ("Complexity" (1; #8), 11.0),
#   ("GrayLevelVariance.2" (1; #28), 11.0),
#   ("MCC" (1; #56), 11.0),
#   ("Autocorrelation" (1; #2), 10.0),
#   ("Correlation" (1; #11), 10.0),
#   ("LowGrayLevelZoneEmphasis" (1; #55), 10.0),
#   ("ShortRunHighGrayLevelEmphasis" (1; #72), 10.0),
#   ("ClusterProminence" (1; #4), 9.0),
#   ("Imc1" (1; #36), 9.0),
#   ("LargeAreaLowGrayLevelEmphasis" (1; #46), 9.0),
#   ("Minimum" (1; #62), 9.0),
#   ("Range" (1; #63), 9.0),
#   ("JointEnergy" (1; #41), 8.0),
#   ("LongRunLowGrayLevelEmphasis" (1; #52), 8.0),
#   ("Mean" (1; #59), 8.0),
#   ("DifferenceAverage" (1; #16), 7.0),
#   ("DifferenceEntropy" (1; #17), 7.0),
#   ("GrayLevelNonUniformityNormalized.1" (1; #25), 7.0),
#   ("MaximumProbability" (1; #58), 7.0),
#   ("SizeZoneNonUniformity" (1; #74), 7.0),
#   ("SmallAreaLowGrayLevelEmphasis" (1; #79), 7.0),
#   ("JointAverage" (1; #40), 6.0),
#   ("LongRunEmphasis" (1; #50), 6.0),
#   ("Strength" (1; #83), 6.0),
#   ("ZoneEntropy" (1; #90), 6.0),
#   ("DependenceVariance" (1; #15), 5.0),
#   ("Id" (1; #32), 5.0),
#   ("Imc2" (1; #37), 5.0),
#   ("LowGrayLevelRunEmphasis" (1; #54), 5.0),
#   ("RootMeanSquared" (1; #65), 5.0),
#   ("ShortRunLowGrayLevelEmphasis" (1; #73), 5.0),
#   ("TotalEnergy" (1; #87), 5.0),
#   ("Energy" (1; #19), 4.0),
#   ("GrayLevelNonUniformity" (1; #21), 4.0),
#   ("HighGrayLevelRunEmphasis" (1; #30), 4.0),
#   ("InterquartileRange" (1; #38), 4.0),
#   ("JointEntropy" (1; #42), 4.0),
#   ("RunPercentage" (1; #69), 4.0),
#   ("SmallDependenceEmphasis" (1; #80), 4.0),
#   ("Uniformity" (1; #88), 4.0),
#   ("ClusterTendency" (1; #6), 3.0),
#   ("DependenceNonUniformityNormalized" (1; #14), 3.0),
#   ("GrayLevelNonUniformityNormalized" (1; #24), 3.0),
#   ("Idm" (1; #33), 3.0),
#   ("RunVariance" (1; #70), 3.0),
#   ("SmallAreaEmphasis" (1; #77), 3.0),
#   ("SumAverage" (1; #84), 3.0),
#   ("SumEntropy" (1; #85), 3.0),
#   ("SumSquares" (1; #86), 3.0),
#   ("ZonePercentage" (1; #91), 3.0),
#   ("DependenceNonUniformity" (1; #13), 2.0),
#   ("Entropy" (1; #20), 2.0),
#   ("GrayLevelVariance" (1; #26), 2.0),
#   ("GrayLevelVariance.1" (1; #27), 2.0),
#   ("HighGrayLevelEmphasis" (1; #29), 2.0),
#   ("LargeDependenceEmphasis" (1; #47), 2.0),
#   ("LowGrayLevelEmphasis" (1; #53), 2.0),
#   ("RunEntropy" (1; #66), 2.0),
#   ("RunLengthNonUniformity" (1; #67), 2.0),
#   ("GrayLevelNonUniformity.1" (1; #22), 1.0),
#   ("MeanAbsoluteDeviation" (1; #60), 1.0),
#   ("RunLengthNonUniformityNormalized" (1; #68), 1.0),
#   ("Variance" (1; #89), 1.0),
#   ("ZoneVariance" (1; #92), 1.0)]}

# %%
# Model self evaluation
model.make_inspector().evaluation()
# Out:
# Evaluation(num_examples=None, accuracy=0.928826630115509, loss=0.3512187898159027, rmse=None, ndcg=None, aucs=None, auuc=None, qini=None)

# %%
logs = model.make_inspector().training_logs()

plt.figure(figsize=(12, 4))
plt.subplot(1, 2, 1)
plt.plot([log.num_trees for log in logs], [log.evaluation.accuracy for log in logs])
plt.xlabel("Number of trees")
plt.ylabel("Accuracy (out-of-bag)")
plt.subplot(1, 2, 2)
plt.plot([log.num_trees for log in logs], [log.evaluation.loss for log in logs])
plt.xlabel("Number of trees")
plt.ylabel("Logloss (out-of-bag)")
plt.show()

# %% [markdown]
# Calculate the score of our hold-out validation dataset

# %%
predictions = model.predict(val_ds)
y_true      = validation_data["label"]

from sklearn.metrics import roc_auc_score
ROC_AUC = roc_auc_score(y_true, predictions)
print("The ROC AUC score is %.5f" % ROC_AUC )
# Out:
# 1/2 [==============>...............] - ETA: 0s
# 2/2 [==============================] - 0s 27ms/step
# The ROC AUC score is 0.99827

# %%
# Compute binary classification metrics with sklearn
import numpy as np
from sklearn.metrics import (
    accuracy_score,
    precision_score,
    recall_score,
    f1_score,
    roc_auc_score,
    average_precision_score,
    confusion_matrix,
    classification_report,
    matthews_corrcoef,
    log_loss,
    brier_score_loss,
)

# Get predictions (probabilities or class labels)
preds = model.predict(test_ds)
# If model outputs probabilities, convert to labels by threshold 0.5
if preds.ndim == 2:
    # For TFDF classification, preds may be class probabilities with shape (N, 2)
    if preds.shape[1] == 2:
        pos_probs = preds[:, 1]
    else:
        # If single-probability column (positive class)
        pos_probs = preds[:, -1]
    y_pred = (pos_probs >= 0.5).astype(int)
else:
    # Already class labels
    y_pred = preds.astype(int)
    pos_probs = None

# Ground truth labels (must be 0/1 integers)
y_true = test_data["label"].astype(int).to_numpy()

# Core metrics
metrics = {}
metrics["accuracy"] = accuracy_score(y_true, y_pred)
metrics["precision"] = precision_score(y_true, y_pred, zero_division=0)
metrics["recall"] = recall_score(y_true, y_pred, zero_division=0)
metrics["f1"] = f1_score(y_true, y_pred, zero_division=0)
metrics["mcc"] = matthews_corrcoef(y_true, y_pred)

# Probabilistic metrics (only if we have probabilities)
if pos_probs is not None:
    metrics["roc_auc"] = roc_auc_score(y_true, pos_probs)
    metrics["pr_auc"] = average_precision_score(y_true, pos_probs)
    metrics["log_loss"] = log_loss(y_true, pos_probs, labels=[0,1])
    metrics["brier_score"] = brier_score_loss(y_true, pos_probs)

# Confusion matrix and detailed report
cm = confusion_matrix(y_true, y_pred, labels=[0,1])
report = classification_report(y_true, y_pred, digits=4)

print("Sklearn binary metrics:")
for k, v in metrics.items():
    print(f"{k}: {v:.4f}")
print("\nConfusion matrix:\n", cm)
print("\nClassification report:\n", report)
# Out:
# 1/5 [=====>........................] - ETA: 0s
# 3/5 [=================>............] - ETA: 0s
# 5/5 [==============================] - 0s 24ms/step
# Sklearn binary metrics:
# accuracy: 0.9629
# precision: 0.7827
# recall: 0.8610
# f1: 0.8200
# mcc: 0.8005
# roc_auc: 0.9749
# pr_auc: 0.8926
# log_loss: 0.1208
# brier_score: 0.0301
#
# Confusion matrix:
#  [[3671   98]
#  [  57  353]]
#
# Classification report:
#                precision    recall  f1-score   support
#
#            0     0.9847    0.9740    0.9793      3769
#            1     0.7827    0.8610    0.8200       410
#
#     accuracy                         0.9629      4179
#    macro avg     0.8837    0.9175    0.8997      4179
# weighted avg     0.9649    0.9629    0.9637      4179
