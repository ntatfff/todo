# %%
# Import packages and modules
import numpy  as np
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow_decision_forests as tfdf

from sklearn.model_selection import train_test_split
# Out:
# 2026-09-11 08:20:57.460660: I tensorflow/core/util/port.cc:113] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2026-09-11 08:20:57.499906: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2026-09-11 08:21:01.800598: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
# Check the version of TensorFlow Decision Forests
print("Found TensorFlow Decision Forests v" + tfdf.__version__)
# Out:
# Found TensorFlow Decision Forests v1.9.1

# %%
datasetPath = "dataset/10p/all/kernel3/"

# %%
# Parameters
datasetPath = "dataset/10p/glrlm/kernel4/"

# %%
# train/validation/test = 70/10/20
train_data = pd.read_csv(f"{datasetPath}dataset.train.csv")
validation_data = pd.read_csv(f"{datasetPath}dataset.validation.csv")
test_data = pd.read_csv(f"{datasetPath}dataset.test.csv")

# %%
from sklearn.utils.class_weight import compute_class_weight

# tinh class weight tren tap train
classes = np.array([0, 1])
weights = compute_class_weight(class_weight="balanced", classes=classes, y=train_data["label"])
class_weight = {0: weights[0], 1: weights[1]}

# gan sample_weight cho tung dong
train_data["sample_weight"] = train_data["label"].map(class_weight)
validation_data["sample_weight"] = validation_data["label"].map(class_weight)
test_data["sample_weight"] = test_data["label"].map(class_weight)

# Convert the dataset into a TensorFlow dataset.
train_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    train_data, label="label", weight="sample_weight"
)         
val_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    validation_data, label="label", weight="sample_weight"
)
test_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    test_data, label="label", weight="sample_weight"
)
# Out:
# 2026-09-11 08:21:14.696605: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:984] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2026-09-11 08:21:14.698004: W tensorflow/core/common_runtime/gpu/gpu_device.cc:2251] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...

# %%
import keras

# %%
# %%time

# Train a Random Forest model.
model = tfdf.keras.RandomForestModel()

# Add evaluation metrics
model.compile(
    metrics=["accuracy"]
)
model.fit(x=train_ds)

# # Train a Gradient Boosted Trees model.
# model = tfdf.keras.GradientBoostedTreesModel(num_trees=1500)
# model.fit(train_ds)
# Out:
# Use /tmp/tmpjz2w3v8a as temporary training directory
# Reading training dataset...
# Training dataset read in 0:00:02.477469. Found 13938 examples.
# Training model...
# Model trained in 0:00:00.918654
# Compiling model...
# [INFO 26-09-11 08:21:18.0641 UTC kernel.cc:1233] Loading model from path /tmp/tmpjz2w3v8a/model/ with prefix 4eb844d7b3444989
# [INFO 26-09-11 08:21:18.2112 UTC decision_forest.cc:734] Model loaded with 300 root(s), 126280 node(s), and 16 input feature(s).
# [INFO 26-09-11 08:21:18.2113 UTC abstract_model.cc:1362] Engine "RandomForestOptPred" built
# [INFO 26-09-11 08:21:18.2113 UTC kernel.cc:1061] Use fast generic engine
# Model compiled.
# CPU times: user 13 s, sys: 224 ms, total: 13.3 s
# Wall time: 6.4 s

# %%
# Evaluate the model
evaluate = model.evaluate(val_ds, return_dict=True)
print()

for name, value in evaluate.items():
    print(f"{name}: {value:.4f}")
# Out:
# WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 1/2 [==============>...............] - ETA: 2s - loss: 0.0000e+00 - accuracy: 0.9850
# 2/2 [==============================] - 3s 20ms/step - loss: 0.0000e+00 - accuracy: 0.9867
# loss: 0.0000
# accuracy: 0.9867

# %%
# Model Summary
model.summary()
# Out:
# Model: "random_forest_model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
# =================================================================
# Total params: 1 (1.00 Byte)
# Trainable params: 0 (0.00 Byte)
# Non-trainable params: 1 (1.00 Byte)
# _________________________________________________________________
# Type: "RANDOM_FOREST"
# Task: CLASSIFICATION
# Label: "__LABEL"
#
# Input Features (16):
# 	GrayLevelNonUniformity
# 	GrayLevelNonUniformityNormalized
# 	GrayLevelVariance
# 	HighGrayLevelRunEmphasis
# 	LongRunEmphasis
# 	LongRunHighGrayLevelEmphasis
# 	LongRunLowGrayLevelEmphasis
# 	LowGrayLevelRunEmphasis
# 	RunEntropy
# 	RunLengthNonUniformity
# 	RunLengthNonUniformityNormalized
# 	RunPercentage
# 	RunVariance
# 	ShortRunEmphasis
# 	ShortRunHighGrayLevelEmphasis
# 	ShortRunLowGrayLevelEmphasis
#
# Trained with weights
#
# Variable Importance: INV_MEAN_MIN_DEPTH:
#     1.     "LongRunHighGrayLevelEmphasis"  0.252998 ################
#     2.         "HighGrayLevelRunEmphasis"  0.159515 #####
#     3.     "ShortRunLowGrayLevelEmphasis"  0.141864 ###
#     4.    "ShortRunHighGrayLevelEmphasis"  0.141565 ###
#     5.          "LowGrayLevelRunEmphasis"  0.128791 ##
#     6.      "LongRunLowGrayLevelEmphasis"  0.126993 ##
#     7.                       "RunEntropy"  0.122897 #
#     8.           "GrayLevelNonUniformity"  0.117509 #
#     9.                      "RunVariance"  0.116899 #
#    10.                 "ShortRunEmphasis"  0.113248
#    11.                  "LongRunEmphasis"  0.112755
#    12. "GrayLevelNonUniformityNormalized"  0.110591
#    13. "RunLengthNonUniformityNormalized"  0.109740
#    14.                "GrayLevelVariance"  0.108265
#    15.                    "RunPercentage"  0.105863
#    16.           "RunLengthNonUniformity"  0.105729
#
# Variable Importance: NUM_AS_ROOT:
#     1.     "LongRunHighGrayLevelEmphasis" 95.000000 ################
#     2.         "HighGrayLevelRunEmphasis" 60.000000 ##########
#     3.     "ShortRunLowGrayLevelEmphasis" 48.000000 ########
#     4.    "ShortRunHighGrayLevelEmphasis" 42.000000 ######
#     5.          "LowGrayLevelRunEmphasis" 24.000000 ###
#     6.      "LongRunLowGrayLevelEmphasis" 18.000000 ##
#     7.           "GrayLevelNonUniformity"  7.000000 #
#     8. "GrayLevelNonUniformityNormalized"  3.000000
#     9.                  "LongRunEmphasis"  1.000000
#    10.                       "RunEntropy"  1.000000
#    11.                      "RunVariance"  1.000000
#
# Variable Importance: NUM_NODES:
#     1.     "LongRunHighGrayLevelEmphasis" 5549.000000 ################
#     2.                       "RunEntropy" 5276.000000 ##############
#     3.                "GrayLevelVariance" 4478.000000 #########
#     4.           "GrayLevelNonUniformity" 4381.000000 #########
#     5.         "HighGrayLevelRunEmphasis" 4327.000000 ########
#     6.    "ShortRunHighGrayLevelEmphasis" 4301.000000 ########
#     7.     "ShortRunLowGrayLevelEmphasis" 4201.000000 ########
#     8. "GrayLevelNonUniformityNormalized" 4137.000000 #######
#     9.          "LowGrayLevelRunEmphasis" 3936.000000 ######
#    10.                      "RunVariance" 3766.000000 #####
#    11.      "LongRunLowGrayLevelEmphasis" 3761.000000 #####
#    12.                  "LongRunEmphasis" 3230.000000 ##
#    13. "RunLengthNonUniformityNormalized" 3077.000000 #
#    14.                 "ShortRunEmphasis" 2999.000000 #
#    15.           "RunLengthNonUniformity" 2791.000000
#    16.                    "RunPercentage" 2780.000000
#
# Variable Importance: SUM_SCORE:
#     1.     "LongRunHighGrayLevelEmphasis" 658568.879738 ################
#     2.         "HighGrayLevelRunEmphasis" 377928.331654 ########
#     3.    "ShortRunHighGrayLevelEmphasis" 287922.918483 ######
#     4.     "ShortRunLowGrayLevelEmphasis" 261372.483732 #####
#     5.          "LowGrayLevelRunEmphasis" 177344.415789 ###
#     6.      "LongRunLowGrayLevelEmphasis" 147650.624396 ##
#     7.                       "RunEntropy" 133874.108562 ##
#     8.           "GrayLevelNonUniformity" 98126.922336 #
#     9.                      "RunVariance" 88391.915293
#    10. "GrayLevelNonUniformityNormalized" 83145.437839
#    11.                "GrayLevelVariance" 82615.183950
#    12.                  "LongRunEmphasis" 77200.457602
#    13.                 "ShortRunEmphasis" 72555.961389
#    14. "RunLengthNonUniformityNormalized" 68171.584397
#    15.                    "RunPercentage" 57963.387905
#    16.           "RunLengthNonUniformity" 56973.811683
#
#
#
# Winner takes all: true
# Out-of-bag evaluation: accuracy:0.869564 logloss:0.541502
# Number of trees: 300
# Total number of nodes: 126280
#
# Number of nodes by tree:
# Count: 300 Average: 420.933 StdDev: 23.0158
# Min: 355 Max: 483 Ignored: 0
# ----------------------------------------------
# [ 355, 361)  1   0.33%   0.33%
# [ 361, 367)  3   1.00%   1.33% #
# [ 367, 374)  1   0.33%   1.67%
# [ 374, 380)  7   2.33%   4.00% ##
# [ 380, 387)  8   2.67%   6.67% ##
# [ 387, 393) 14   4.67%  11.33% ####
# [ 393, 400) 24   8.00%  19.33% #######
# [ 400, 406) 23   7.67%  27.00% ######
# [ 406, 413) 23   7.67%  34.67% ######
# [ 413, 419) 26   8.67%  43.33% #######
# [ 419, 425) 32  10.67%  54.00% #########
# [ 425, 432) 36  12.00%  66.00% ##########
# [ 432, 438) 26   8.67%  74.67% #######
# [ 438, 445) 25   8.33%  83.00% #######
# [ 445, 451) 23   7.67%  90.67% ######
# [ 451, 458) 18   6.00%  96.67% #####
# [ 458, 464)  4   1.33%  98.00% #
# [ 464, 471)  3   1.00%  99.00% #
# [ 471, 477)  2   0.67%  99.67% #
# [ 477, 483]  1   0.33% 100.00%
#
# Depth by leafs:
# Count: 63290 Average: 10.1188 StdDev: 2.75335
# Min: 1 Max: 15 Ignored: 0
# ----------------------------------------------
# [  1,  2)    1   0.00%   0.00%
# [  2,  3)   41   0.06%   0.07%
# [  3,  4)  311   0.49%   0.56%
# [  4,  5)  772   1.22%   1.78% #
# [  5,  6) 1546   2.44%   4.22% ##
# [  6,  7) 3320   5.25%   9.47% ####
# [  7,  8) 5511   8.71%  18.17% #######
# [  8,  9) 7274  11.49%  29.67% #########
# [  9, 10) 8178  12.92%  42.59% ##########
# [ 10, 11) 8264  13.06%  55.65% ##########
# [ 11, 12) 7752  12.25%  67.89% #########
# [ 12, 13) 6624  10.47%  78.36% ########
# [ 13, 14) 5293   8.36%  86.72% ######
# [ 14, 15) 3961   6.26%  92.98% #####
# [ 15, 15] 4442   7.02% 100.00% #####
#
# Number of training obs by leaf:
# Count: 63290 Average: 66.0673 StdDev: 255.753
# Min: 5 Max: 4137 Ignored: 0
# ----------------------------------------------
# [    5,  211) 59587  94.15%  94.15% ##########
# [  211,  418)  1604   2.53%  96.68%
# [  418,  624)   594   0.94%  97.62%
# [  624,  831)   322   0.51%  98.13%
# [  831, 1038)   196   0.31%  98.44%
# [ 1038, 1244)   186   0.29%  98.73%
# [ 1244, 1451)   139   0.22%  98.95%
# [ 1451, 1658)   104   0.16%  99.12%
# [ 1658, 1864)   106   0.17%  99.29%
# [ 1864, 2071)   159   0.25%  99.54%
# [ 2071, 2278)    94   0.15%  99.69%
# [ 2278, 2484)    60   0.09%  99.78%
# [ 2484, 2691)    46   0.07%  99.85%
# [ 2691, 2898)    25   0.04%  99.89%
# [ 2898, 3104)    23   0.04%  99.93%
# [ 3104, 3311)    14   0.02%  99.95%
# [ 3311, 3518)    16   0.03%  99.98%
# [ 3518, 3724)    10   0.02%  99.99%
# [ 3724, 3931)     3   0.00% 100.00%
# [ 3931, 4137]     2   0.00% 100.00%
#
# Attribute in nodes:
# 	5549 : LongRunHighGrayLevelEmphasis [NUMERICAL]
# 	5276 : RunEntropy [NUMERICAL]
# 	4478 : GrayLevelVariance [NUMERICAL]
# 	4381 : GrayLevelNonUniformity [NUMERICAL]
# 	4327 : HighGrayLevelRunEmphasis [NUMERICAL]
# 	4301 : ShortRunHighGrayLevelEmphasis [NUMERICAL]
# 	4201 : ShortRunLowGrayLevelEmphasis [NUMERICAL]
# 	4137 : GrayLevelNonUniformityNormalized [NUMERICAL]
# 	3936 : LowGrayLevelRunEmphasis [NUMERICAL]
# 	3766 : RunVariance [NUMERICAL]
# 	3761 : LongRunLowGrayLevelEmphasis [NUMERICAL]
# 	3230 : LongRunEmphasis [NUMERICAL]
# 	3077 : RunLengthNonUniformityNormalized [NUMERICAL]
# 	2999 : ShortRunEmphasis [NUMERICAL]
# 	2791 : RunLengthNonUniformity [NUMERICAL]
# 	2780 : RunPercentage [NUMERICAL]
#
# Attribute in nodes with depth <= 0:
# 	95 : LongRunHighGrayLevelEmphasis [NUMERICAL]
# 	60 : HighGrayLevelRunEmphasis [NUMERICAL]
# 	48 : ShortRunLowGrayLevelEmphasis [NUMERICAL]
# 	42 : ShortRunHighGrayLevelEmphasis [NUMERICAL]
# 	24 : LowGrayLevelRunEmphasis [NUMERICAL]
# 	18 : LongRunLowGrayLevelEmphasis [NUMERICAL]
# 	7 : GrayLevelNonUniformity [NUMERICAL]
# 	3 : GrayLevelNonUniformityNormalized [NUMERICAL]
# 	1 : RunVariance [NUMERICAL]
# 	1 : RunEntropy [NUMERICAL]
# 	1 : LongRunEmphasis [NUMERICAL]
#
# Attribute in nodes with depth <= 1:
# 	270 : LongRunHighGrayLevelEmphasis [NUMERICAL]
# 	158 : HighGrayLevelRunEmphasis [NUMERICAL]
# 	113 : ShortRunHighGrayLevelEmphasis [NUMERICAL]
# 	111 : ShortRunLowGrayLevelEmphasis [NUMERICAL]
# 	79 : LowGrayLevelRunEmphasis [NUMERICAL]
# 	71 : LongRunLowGrayLevelEmphasis [NUMERICAL]
# 	21 : GrayLevelNonUniformity [NUMERICAL]
# 	19 : RunEntropy [NUMERICAL]
# 	12 : GrayLevelNonUniformityNormalized [NUMERICAL]
# 	11 : RunVariance [NUMERICAL]
# 	10 : ShortRunEmphasis [NUMERICAL]
# 	7 : LongRunEmphasis [NUMERICAL]
# 	6 : GrayLevelVariance [NUMERICAL]
# 	5 : RunLengthNonUniformityNormalized [NUMERICAL]
# 	4 : RunLengthNonUniformity [NUMERICAL]
# 	2 : RunPercentage [NUMERICAL]
#
# Attribute in nodes with depth <= 2:
# 	485 : LongRunHighGrayLevelEmphasis [NUMERICAL]
# 	243 : HighGrayLevelRunEmphasis [NUMERICAL]
# 	196 : ShortRunLowGrayLevelEmphasis [NUMERICAL]
# 	177 : ShortRunHighGrayLevelEmphasis [NUMERICAL]
# 	166 : LowGrayLevelRunEmphasis [NUMERICAL]
# 	150 : LongRunLowGrayLevelEmphasis [NUMERICAL]
# 	88 : GrayLevelNonUniformity [NUMERICAL]
# 	81 : LongRunEmphasis [NUMERICAL]
# 	77 : ShortRunEmphasis [NUMERICAL]
# 	75 : RunVariance [NUMERICAL]
# 	68 : RunEntropy [NUMERICAL]
# 	61 : RunPercentage [NUMERICAL]
# 	59 : GrayLevelNonUniformityNormalized [NUMERICAL]
# 	55 : RunLengthNonUniformityNormalized [NUMERICAL]
# 	40 : RunLengthNonUniformity [NUMERICAL]
# 	35 : GrayLevelVariance [NUMERICAL]
#
# Attribute in nodes with depth <= 3:
# 	715 : LongRunHighGrayLevelEmphasis [NUMERICAL]
# 	399 : HighGrayLevelRunEmphasis [NUMERICAL]
# 	320 : ShortRunLowGrayLevelEmphasis [NUMERICAL]
# 	303 : ShortRunHighGrayLevelEmphasis [NUMERICAL]
# 	298 : LowGrayLevelRunEmphasis [NUMERICAL]
# 	271 : LongRunLowGrayLevelEmphasis [NUMERICAL]
# 	245 : GrayLevelNonUniformity [NUMERICAL]
# 	214 : RunEntropy [NUMERICAL]
# 	205 : RunVariance [NUMERICAL]
# 	196 : LongRunEmphasis [NUMERICAL]
# 	183 : ShortRunEmphasis [NUMERICAL]
# 	173 : GrayLevelNonUniformityNormalized [NUMERICAL]
# 	153 : RunPercentage [NUMERICAL]
# 	140 : GrayLevelVariance [NUMERICAL]
# 	124 : RunLengthNonUniformityNormalized [NUMERICAL]
# 	120 : RunLengthNonUniformity [NUMERICAL]
#
# Attribute in nodes with depth <= 5:
# 	1441 : LongRunHighGrayLevelEmphasis [NUMERICAL]
# 	991 : RunEntropy [NUMERICAL]
# 	981 : HighGrayLevelRunEmphasis [NUMERICAL]
# 	910 : ShortRunHighGrayLevelEmphasis [NUMERICAL]
# 	855 : ShortRunLowGrayLevelEmphasis [NUMERICAL]
# 	839 : GrayLevelNonUniformity [NUMERICAL]
# 	798 : LowGrayLevelRunEmphasis [NUMERICAL]
# 	744 : LongRunLowGrayLevelEmphasis [NUMERICAL]
# 	719 : RunVariance [NUMERICAL]
# 	708 : GrayLevelVariance [NUMERICAL]
# 	700 : GrayLevelNonUniformityNormalized [NUMERICAL]
# 	585 : LongRunEmphasis [NUMERICAL]
# 	514 : ShortRunEmphasis [NUMERICAL]
# 	494 : RunPercentage [NUMERICAL]
# 	488 : RunLengthNonUniformityNormalized [NUMERICAL]
# 	448 : RunLengthNonUniformity [NUMERICAL]
#
# Condition type in nodes:
# 	62990 : HigherCondition
# Condition type in nodes with depth <= 0:
# 	300 : HigherCondition
# Condition type in nodes with depth <= 1:
# 	899 : HigherCondition
# Condition type in nodes with depth <= 2:
# 	2056 : HigherCondition
# Condition type in nodes with depth <= 3:
# 	4059 : HigherCondition
# Condition type in nodes with depth <= 5:
# 	12215 : HigherCondition
# Node format: NOT_SET
#
# Training OOB:
# 	trees: 1, Out-of-bag evaluation: accuracy:0.859631 logloss:5.05942
# 	trees: 11, Out-of-bag evaluation: accuracy:0.848519 logloss:2.35356
# 	trees: 21, Out-of-bag evaluation: accuracy:0.859786 logloss:1.51518
# 	trees: 31, Out-of-bag evaluation: accuracy:0.862389 logloss:1.19979
# 	trees: 41, Out-of-bag evaluation: accuracy:0.863893 logloss:1.00887
# 	trees: 51, Out-of-bag evaluation: accuracy:0.867279 logloss:0.843731
# 	trees: 61, Out-of-bag evaluation: accuracy:0.864021 logloss:0.788956
# 	trees: 71, Out-of-bag evaluation: accuracy:0.865186 logloss:0.786649
# 	trees: 81, Out-of-bag evaluation: accuracy:0.865493 logloss:0.767756
# 	trees: 91, Out-of-bag evaluation: accuracy:0.86429 logloss:0.746454
# 	trees: 101, Out-of-bag evaluation: accuracy:0.868329 logloss:0.726366
# 	trees: 111, Out-of-bag evaluation: accuracy:0.870076 logloss:0.723775
# 	trees: 121, Out-of-bag evaluation: accuracy:0.870383 logloss:0.688382
# 	trees: 131, Out-of-bag evaluation: accuracy:0.869142 logloss:0.685881
# 	trees: 141, Out-of-bag evaluation: accuracy:0.872483 logloss:0.66865
# 	trees: 151, Out-of-bag evaluation: accuracy:0.869257 logloss:0.650796
# 	trees: 161, Out-of-bag evaluation: accuracy:0.870966 logloss:0.632352
# 	trees: 171, Out-of-bag evaluation: accuracy:0.871471 logloss:0.630349
# 	trees: 181, Out-of-bag evaluation: accuracy:0.86813 logloss:0.628731
# 	trees: 191, Out-of-bag evaluation: accuracy:0.867701 logloss:0.611922
# 	trees: 201, Out-of-bag evaluation: accuracy:0.870697 logloss:0.611413
# 	trees: 211, Out-of-bag evaluation: accuracy:0.869801 logloss:0.611307
# 	trees: 221, Out-of-bag evaluation: accuracy:0.868245 logloss:0.59414
# 	trees: 231, Out-of-bag evaluation: accuracy:0.868322 logloss:0.593993
# 	trees: 241, Out-of-bag evaluation: accuracy:0.869295 logloss:0.594087
# 	trees: 251, Out-of-bag evaluation: accuracy:0.869487 logloss:0.576744
# 	trees: 261, Out-of-bag evaluation: accuracy:0.870422 logloss:0.577313
# 	trees: 271, Out-of-bag evaluation: accuracy:0.869839 logloss:0.576231
# 	trees: 281, Out-of-bag evaluation: accuracy:0.870537 logloss:0.576261
# 	trees: 291, Out-of-bag evaluation: accuracy:0.869878 logloss:0.541811
# 	trees: 300, Out-of-bag evaluation: accuracy:0.869564 logloss:0.541502

# %%
# Model features
model.make_inspector().features()
# Out:
# ["GrayLevelNonUniformity" (1; #0),
#  "GrayLevelNonUniformityNormalized" (1; #1),
#  "GrayLevelVariance" (1; #2),
#  "HighGrayLevelRunEmphasis" (1; #3),
#  "LongRunEmphasis" (1; #4),
#  "LongRunHighGrayLevelEmphasis" (1; #5),
#  "LongRunLowGrayLevelEmphasis" (1; #6),
#  "LowGrayLevelRunEmphasis" (1; #7),
#  "RunEntropy" (1; #8),
#  "RunLengthNonUniformity" (1; #9),
#  "RunLengthNonUniformityNormalized" (1; #10),
#  "RunPercentage" (1; #11),
#  "RunVariance" (1; #12),
#  "ShortRunEmphasis" (1; #13),
#  "ShortRunHighGrayLevelEmphasis" (1; #14),
#  "ShortRunLowGrayLevelEmphasis" (1; #15)]

# %%
# Feature importance
model.make_inspector().variable_importances()
# Out:
# {'INV_MEAN_MIN_DEPTH': [("LongRunHighGrayLevelEmphasis" (1; #5),
#    0.2529976464875079),
#   ("HighGrayLevelRunEmphasis" (1; #3), 0.1595153024777437),
#   ("ShortRunLowGrayLevelEmphasis" (1; #15), 0.14186378945906253),
#   ("ShortRunHighGrayLevelEmphasis" (1; #14), 0.14156538878145872),
#   ("LowGrayLevelRunEmphasis" (1; #7), 0.12879104903241423),
#   ("LongRunLowGrayLevelEmphasis" (1; #6), 0.12699349212105165),
#   ("RunEntropy" (1; #8), 0.12289727409880333),
#   ("GrayLevelNonUniformity" (1; #0), 0.11750895634942819),
#   ("RunVariance" (1; #12), 0.11689908477991276),
#   ("ShortRunEmphasis" (1; #13), 0.1132480924432421),
#   ("LongRunEmphasis" (1; #4), 0.112754765751977),
#   ("GrayLevelNonUniformityNormalized" (1; #1), 0.11059084875532078),
#   ("RunLengthNonUniformityNormalized" (1; #10), 0.10973995492569197),
#   ("GrayLevelVariance" (1; #2), 0.10826540644535153),
#   ("RunPercentage" (1; #11), 0.10586307603429106),
#   ("RunLengthNonUniformity" (1; #9), 0.10572850879220785)],
#  'NUM_AS_ROOT': [("LongRunHighGrayLevelEmphasis" (1; #5), 95.0),
#   ("HighGrayLevelRunEmphasis" (1; #3), 60.0),
#   ("ShortRunLowGrayLevelEmphasis" (1; #15), 48.0),
#   ("ShortRunHighGrayLevelEmphasis" (1; #14), 42.0),
#   ("LowGrayLevelRunEmphasis" (1; #7), 24.0),
#   ("LongRunLowGrayLevelEmphasis" (1; #6), 18.0),
#   ("GrayLevelNonUniformity" (1; #0), 7.0),
#   ("GrayLevelNonUniformityNormalized" (1; #1), 3.0),
#   ("LongRunEmphasis" (1; #4), 1.0),
#   ("RunEntropy" (1; #8), 1.0),
#   ("RunVariance" (1; #12), 1.0)],
#  'SUM_SCORE': [("LongRunHighGrayLevelEmphasis" (1; #5), 658568.8797379977),
#   ("HighGrayLevelRunEmphasis" (1; #3), 377928.3316540283),
#   ("ShortRunHighGrayLevelEmphasis" (1; #14), 287922.91848296346),
#   ("ShortRunLowGrayLevelEmphasis" (1; #15), 261372.4837318072),
#   ("LowGrayLevelRunEmphasis" (1; #7), 177344.41578932028),
#   ("LongRunLowGrayLevelEmphasis" (1; #6), 147650.6243958684),
#   ("RunEntropy" (1; #8), 133874.10856207035),
#   ("GrayLevelNonUniformity" (1; #0), 98126.92233606322),
#   ("RunVariance" (1; #12), 88391.91529288556),
#   ("GrayLevelNonUniformityNormalized" (1; #1), 83145.43783891453),
#   ("GrayLevelVariance" (1; #2), 82615.18395037595),
#   ("LongRunEmphasis" (1; #4), 77200.45760221126),
#   ("ShortRunEmphasis" (1; #13), 72555.9613886618),
#   ("RunLengthNonUniformityNormalized" (1; #10), 68171.58439681416),
#   ("RunPercentage" (1; #11), 57963.38790513805),
#   ("RunLengthNonUniformity" (1; #9), 56973.811683402964)],
#  'NUM_NODES': [("LongRunHighGrayLevelEmphasis" (1; #5), 5549.0),
#   ("RunEntropy" (1; #8), 5276.0),
#   ("GrayLevelVariance" (1; #2), 4478.0),
#   ("GrayLevelNonUniformity" (1; #0), 4381.0),
#   ("HighGrayLevelRunEmphasis" (1; #3), 4327.0),
#   ("ShortRunHighGrayLevelEmphasis" (1; #14), 4301.0),
#   ("ShortRunLowGrayLevelEmphasis" (1; #15), 4201.0),
#   ("GrayLevelNonUniformityNormalized" (1; #1), 4137.0),
#   ("LowGrayLevelRunEmphasis" (1; #7), 3936.0),
#   ("RunVariance" (1; #12), 3766.0),
#   ("LongRunLowGrayLevelEmphasis" (1; #6), 3761.0),
#   ("LongRunEmphasis" (1; #4), 3230.0),
#   ("RunLengthNonUniformityNormalized" (1; #10), 3077.0),
#   ("ShortRunEmphasis" (1; #13), 2999.0),
#   ("RunLengthNonUniformity" (1; #9), 2791.0),
#   ("RunPercentage" (1; #11), 2780.0)]}

# %%
# Model self evaluation
model.make_inspector().evaluation()
# Out:
# Evaluation(num_examples=13938, accuracy=0.8695639952118432, loss=0.5415016263110242, rmse=None, ndcg=None, aucs=None, auuc=None, qini=None)

# %%
logs = model.make_inspector().training_logs()

plt.figure(figsize=(12, 4))
plt.subplot(1, 2, 1)
plt.plot([log.num_trees for log in logs], [log.evaluation.accuracy for log in logs])
plt.xlabel("Number of trees")
plt.ylabel("Accuracy (out-of-bag)")
plt.subplot(1, 2, 2)
plt.plot([log.num_trees for log in logs], [log.evaluation.loss for log in logs])
plt.xlabel("Number of trees")
plt.ylabel("Logloss (out-of-bag)")
plt.show()

# %% [markdown]
# Calculate the score of our hold-out validation dataset

# %%
predictions = model.predict(val_ds)
y_true      = validation_data["label"]

from sklearn.metrics import roc_auc_score
ROC_AUC = roc_auc_score(y_true, predictions)
print("The ROC AUC score is %.5f" % ROC_AUC )
# Out:
# 1/2 [==============>...............] - ETA: 0s
# 2/2 [==============================] - 0s 14ms/step
# The ROC AUC score is 0.99803

# %%
# Compute binary classification metrics with sklearn
import numpy as np
from sklearn.metrics import (
    accuracy_score,
    precision_score,
    recall_score,
    f1_score,
    roc_auc_score,
    average_precision_score,
    confusion_matrix,
    classification_report,
    matthews_corrcoef,
    log_loss,
    brier_score_loss,
)

# Get predictions (probabilities or class labels)
preds = model.predict(test_ds)
# If model outputs probabilities, convert to labels by threshold 0.5
if preds.ndim == 2:
    # For TFDF classification, preds may be class probabilities with shape (N, 2)
    if preds.shape[1] == 2:
        pos_probs = preds[:, 1]
    else:
        # If single-probability column (positive class)
        pos_probs = preds[:, -1]
    y_pred = (pos_probs >= 0.5).astype(int)
else:
    # Already class labels
    y_pred = preds.astype(int)
    pos_probs = None

# Ground truth labels (must be 0/1 integers)
y_true = test_data["label"].astype(int).to_numpy()

# Core metrics
metrics = {}
metrics["accuracy"] = accuracy_score(y_true, y_pred)
metrics["precision"] = precision_score(y_true, y_pred, zero_division=0)
metrics["recall"] = recall_score(y_true, y_pred, zero_division=0)
metrics["f1"] = f1_score(y_true, y_pred, zero_division=0)
metrics["mcc"] = matthews_corrcoef(y_true, y_pred)

# Probabilistic metrics (only if we have probabilities)
if pos_probs is not None:
    metrics["roc_auc"] = roc_auc_score(y_true, pos_probs)
    metrics["pr_auc"] = average_precision_score(y_true, pos_probs)
    metrics["log_loss"] = log_loss(y_true, pos_probs, labels=[0,1])
    metrics["brier_score"] = brier_score_loss(y_true, pos_probs)

# Confusion matrix and detailed report
cm = confusion_matrix(y_true, y_pred, labels=[0,1])
report = classification_report(y_true, y_pred, digits=4)

print("Sklearn binary metrics:")
for k, v in metrics.items():
    print(f"{k}: {v:.4f}")
print("\nConfusion matrix:\n", cm)
print("\nClassification report:\n", report)
# Out:
# 1/5 [=====>........................] - ETA: 0s
# 5/5 [==============================] - 0s 12ms/step
# Sklearn binary metrics:
# accuracy: 0.9615
# precision: 0.8302
# recall: 0.7634
# f1: 0.7954
# mcc: 0.7750
# roc_auc: 0.9559
# pr_auc: 0.8540
# log_loss: 0.1454
# brier_score: 0.0304
#
# Confusion matrix:
#  [[3705   64]
#  [  97  313]]
#
# Classification report:
#                precision    recall  f1-score   support
#
#            0     0.9745    0.9830    0.9787      3769
#            1     0.8302    0.7634    0.7954       410
#
#     accuracy                         0.9615      4179
#    macro avg     0.9024    0.8732    0.8871      4179
# weighted avg     0.9603    0.9615    0.9608      4179
