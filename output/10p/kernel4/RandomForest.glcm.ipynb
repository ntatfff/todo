# %%
# Import packages and modules
import numpy  as np
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow_decision_forests as tfdf

from sklearn.model_selection import train_test_split
# Out:
# 2026-09-11 08:19:49.227968: I tensorflow/core/util/port.cc:113] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2026-09-11 08:19:49.269404: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2026-09-11 08:19:53.592086: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
# Check the version of TensorFlow Decision Forests
print("Found TensorFlow Decision Forests v" + tfdf.__version__)
# Out:
# Found TensorFlow Decision Forests v1.9.1

# %%
datasetPath = "dataset/10p/all/kernel3/"

# %%
# Parameters
datasetPath = "dataset/10p/glcm/kernel4/"

# %%
# train/validation/test = 70/10/20
train_data = pd.read_csv(f"{datasetPath}dataset.train.csv")
validation_data = pd.read_csv(f"{datasetPath}dataset.validation.csv")
test_data = pd.read_csv(f"{datasetPath}dataset.test.csv")

# %%
from sklearn.utils.class_weight import compute_class_weight

# tinh class weight tren tap train
classes = np.array([0, 1])
weights = compute_class_weight(class_weight="balanced", classes=classes, y=train_data["label"])
class_weight = {0: weights[0], 1: weights[1]}

# gan sample_weight cho tung dong
train_data["sample_weight"] = train_data["label"].map(class_weight)
validation_data["sample_weight"] = validation_data["label"].map(class_weight)
test_data["sample_weight"] = test_data["label"].map(class_weight)

# Convert the dataset into a TensorFlow dataset.
train_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    train_data, label="label", weight="sample_weight"
)         
val_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    validation_data, label="label", weight="sample_weight"
)
test_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    test_data, label="label", weight="sample_weight"
)
# Out:
# 2026-09-11 08:20:05.533398: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:984] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2026-09-11 08:20:05.534775: W tensorflow/core/common_runtime/gpu/gpu_device.cc:2251] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...

# %%
import keras

# %%
# %%time

# Train a Random Forest model.
model = tfdf.keras.RandomForestModel()

# Add evaluation metrics
model.compile(
    metrics=["accuracy"]
)
model.fit(x=train_ds)

# # Train a Gradient Boosted Trees model.
# model = tfdf.keras.GradientBoostedTreesModel(num_trees=1500)
# model.fit(train_ds)
# Out:
# Use /tmp/tmp4ew73y87 as temporary training directory
# Reading training dataset...
# Training dataset read in 0:00:03.625621. Found 13938 examples.
# Training model...
# Model trained in 0:00:00.947218
# Compiling model...
# [INFO 26-09-11 08:20:10.1278 UTC kernel.cc:1233] Loading model from path /tmp/tmp4ew73y87/model/ with prefix b67eb06a7eb943cb
# [INFO 26-09-11 08:20:10.2427 UTC decision_forest.cc:734] Model loaded with 300 root(s), 101762 node(s), and 24 input feature(s).
# [INFO 26-09-11 08:20:10.2428 UTC abstract_model.cc:1362] Engine "RandomForestOptPred" built
# [INFO 26-09-11 08:20:10.2428 UTC kernel.cc:1061] Use fast generic engine
# Model compiled.
# CPU times: user 14.3 s, sys: 120 ms, total: 14.4 s
# Wall time: 7.69 s

# %%
# Evaluate the model
evaluate = model.evaluate(val_ds, return_dict=True)
print()

for name, value in evaluate.items():
    print(f"{name}: {value:.4f}")
# Out:
# WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 1/2 [==============>...............] - ETA: 2s - loss: 0.0000e+00 - accuracy: 0.9940
# 2/2 [==============================] - 3s 18ms/step - loss: 0.0000e+00 - accuracy: 0.9933
# loss: 0.0000
# accuracy: 0.9933

# %%
# Model Summary
model.summary()
# Out:
# Model: "random_forest_model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
# =================================================================
# Total params: 1 (1.00 Byte)
# Trainable params: 0 (0.00 Byte)
# Non-trainable params: 1 (1.00 Byte)
# _________________________________________________________________
# Type: "RANDOM_FOREST"
# Task: CLASSIFICATION
# Label: "__LABEL"
#
# Input Features (24):
# 	Autocorrelation
# 	ClusterProminence
# 	ClusterShade
# 	ClusterTendency
# 	Contrast
# 	Correlation
# 	DifferenceAverage
# 	DifferenceEntropy
# 	DifferenceVariance
# 	Id
# 	Idm
# 	Idmn
# 	Idn
# 	Imc1
# 	Imc2
# 	InverseVariance
# 	JointAverage
# 	JointEnergy
# 	JointEntropy
# 	MCC
# 	MaximumProbability
# 	SumAverage
# 	SumEntropy
# 	SumSquares
#
# Trained with weights
#
# Variable Importance: INV_MEAN_MIN_DEPTH:
#     1.    "Autocorrelation"  0.186107 ################
#     2.       "JointAverage"  0.176026 ##############
#     3.         "SumAverage"  0.164189 ###########
#     4.    "InverseVariance"  0.127560 ####
#     5.                "MCC"  0.125262 ####
#     6.               "Imc1"  0.124839 ####
#     7.        "Correlation"  0.120098 ###
#     8. "MaximumProbability"  0.118005 ###
#     9.         "SumEntropy"  0.117770 ###
#    10.                "Idn"  0.116295 ##
#    11.               "Idmn"  0.115994 ##
#    12.                "Idm"  0.115533 ##
#    13.                 "Id"  0.115115 ##
#    14.               "Imc2"  0.113843 ##
#    15.       "ClusterShade"  0.112386 ##
#    16.        "JointEnergy"  0.108606 #
#    17.  "DifferenceEntropy"  0.107949 #
#    18.  "DifferenceAverage"  0.107894 #
#    19.           "Contrast"  0.105514
#    20. "DifferenceVariance"  0.104437
#    21.       "JointEntropy"  0.104034
#    22.  "ClusterProminence"  0.102985
#    23.         "SumSquares"  0.101950
#    24.    "ClusterTendency"  0.101461
#
# Variable Importance: NUM_AS_ROOT:
#     1.    "Autocorrelation" 73.000000 ################
#     2.       "JointAverage" 54.000000 ###########
#     3.         "SumAverage" 51.000000 ###########
#     4.         "SumEntropy" 32.000000 ######
#     5.                "MCC" 26.000000 #####
#     6.        "Correlation" 18.000000 ###
#     7.               "Imc2" 13.000000 ##
#     8.               "Imc1" 12.000000 ##
#     9.        "JointEnergy"  7.000000 #
#    10.       "JointEntropy"  5.000000
#    11. "MaximumProbability"  4.000000
#    12.                "Idm"  2.000000
#    13.                 "Id"  1.000000
#    14.               "Idmn"  1.000000
#    15.         "SumSquares"  1.000000
#
# Variable Importance: NUM_NODES:
#     1.                "Idn" 4017.000000 ################
#     2.               "Idmn" 3577.000000 #############
#     3.    "Autocorrelation" 3067.000000 ##########
#     4.       "JointAverage" 2922.000000 #########
#     5.       "ClusterShade" 2916.000000 #########
#     6.         "SumAverage" 2814.000000 ########
#     7.               "Imc1" 2148.000000 ####
#     8.        "Correlation" 2045.000000 ####
#     9.    "InverseVariance" 1995.000000 ####
#    10.               "Imc2" 1913.000000 ###
#    11.           "Contrast" 1906.000000 ###
#    12. "DifferenceVariance" 1885.000000 ###
#    13. "MaximumProbability" 1839.000000 ###
#    14.                "Idm" 1827.000000 ###
#    15.  "DifferenceAverage" 1775.000000 ##
#    16.                "MCC" 1768.000000 ##
#    17.                 "Id" 1725.000000 ##
#    18.  "DifferenceEntropy" 1708.000000 ##
#    19.         "SumEntropy" 1691.000000 ##
#    20.  "ClusterProminence" 1614.000000 #
#    21.        "JointEnergy" 1585.000000 #
#    22.    "ClusterTendency" 1350.000000
#    23.         "SumSquares" 1330.000000
#    24.       "JointEntropy" 1314.000000
#
# Variable Importance: SUM_SCORE:
#     1.    "Autocorrelation" 548743.033773 ################
#     2.       "JointAverage" 477563.120416 #############
#     3.         "SumAverage" 445937.642716 ############
#     4.                "Idn" 131806.106666 ###
#     5.               "Idmn" 118311.510849 ##
#     6.    "InverseVariance" 105842.610958 ##
#     7.               "Imc1" 83586.875796 #
#     8. "MaximumProbability" 73754.454210 #
#     9.                "MCC" 73473.435445 #
#    10.         "SumEntropy" 71481.522338 #
#    11.                "Idm" 69626.952031 #
#    12.       "ClusterShade" 64865.583732 #
#    13.        "Correlation" 64561.679337 #
#    14.                 "Id" 64477.335623 #
#    15.               "Imc2" 60326.800400 #
#    16.        "JointEnergy" 51092.747996
#    17.  "DifferenceAverage" 50994.077805
#    18.           "Contrast" 46210.689105
#    19.  "DifferenceEntropy" 45866.440280
#    20. "DifferenceVariance" 38876.506575
#    21.       "JointEntropy" 31513.253905
#    22.  "ClusterProminence" 30377.244858
#    23.         "SumSquares" 27218.323184
#    24.    "ClusterTendency" 25193.128322
#
#
#
# Winner takes all: true
# Out-of-bag evaluation: accuracy:0.911477 logloss:0.269914
# Number of trees: 300
# Total number of nodes: 101762
#
# Number of nodes by tree:
# Count: 300 Average: 339.207 StdDev: 21.924
# Min: 285 Max: 439 Ignored: 0
# ----------------------------------------------
# [ 285, 292)  2   0.67%   0.67%
# [ 292, 300)  9   3.00%   3.67% ##
# [ 300, 308) 12   4.00%   7.67% ##
# [ 308, 316) 13   4.33%  12.00% ##
# [ 316, 323) 16   5.33%  17.33% ###
# [ 323, 331) 54  18.00%  35.33% ##########
# [ 331, 339) 48  16.00%  51.33% #########
# [ 339, 347) 40  13.33%  64.67% #######
# [ 347, 354) 30  10.00%  74.67% ######
# [ 354, 362) 28   9.33%  84.00% #####
# [ 362, 370) 24   8.00%  92.00% ####
# [ 370, 378) 13   4.33%  96.33% ##
# [ 378, 385)  4   1.33%  97.67% #
# [ 385, 393)  4   1.33%  99.00% #
# [ 393, 401)  2   0.67%  99.67%
# [ 401, 409)  0   0.00%  99.67%
# [ 409, 416)  0   0.00%  99.67%
# [ 416, 424)  0   0.00%  99.67%
# [ 424, 432)  0   0.00%  99.67%
# [ 432, 439]  1   0.33% 100.00%
#
# Depth by leafs:
# Count: 51031 Average: 9.42447 StdDev: 2.58129
# Min: 1 Max: 15 Ignored: 0
# ----------------------------------------------
# [  1,  2)    1   0.00%   0.00%
# [  2,  3)   20   0.04%   0.04%
# [  3,  4)  212   0.42%   0.46%
# [  4,  5)  816   1.60%   2.06% #
# [  5,  6) 2010   3.94%   5.99% ###
# [  6,  7) 3672   7.20%  13.19% #####
# [  7,  8) 5600  10.97%  24.16% ########
# [  8,  9) 6892  13.51%  37.67% #########
# [  9, 10) 7462  14.62%  52.29% ##########
# [ 10, 11) 7104  13.92%  66.21% ##########
# [ 11, 12) 6076  11.91%  78.12% ########
# [ 12, 13) 4540   8.90%  87.02% ######
# [ 13, 14) 3195   6.26%  93.28% ####
# [ 14, 15) 1933   3.79%  97.06% ###
# [ 15, 15] 1498   2.94% 100.00% ##
#
# Number of training obs by leaf:
# Count: 51031 Average: 81.9384 StdDev: 280.697
# Min: 5 Max: 4582 Ignored: 0
# ----------------------------------------------
# [    5,  233) 47455  92.99%  92.99% ##########
# [  233,  462)  1444   2.83%  95.82%
# [  462,  691)   577   1.13%  96.95%
# [  691,  920)   363   0.71%  97.66%
# [  920, 1149)   263   0.52%  98.18%
# [ 1149, 1378)   245   0.48%  98.66%
# [ 1378, 1607)   168   0.33%  98.99%
# [ 1607, 1836)   130   0.25%  99.24%
# [ 1836, 2065)   119   0.23%  99.48%
# [ 2065, 2294)    88   0.17%  99.65%
# [ 2294, 2522)    65   0.13%  99.78%
# [ 2522, 2751)    49   0.10%  99.87%
# [ 2751, 2980)    20   0.04%  99.91%
# [ 2980, 3209)    21   0.04%  99.95%
# [ 3209, 3438)     7   0.01%  99.97%
# [ 3438, 3667)    10   0.02%  99.99%
# [ 3667, 3896)     3   0.01%  99.99%
# [ 3896, 4125)     2   0.00% 100.00%
# [ 4125, 4354)     1   0.00% 100.00%
# [ 4354, 4582]     1   0.00% 100.00%
#
# Attribute in nodes:
# 	4017 : Idn [NUMERICAL]
# 	3577 : Idmn [NUMERICAL]
# 	3067 : Autocorrelation [NUMERICAL]
# 	2922 : JointAverage [NUMERICAL]
# 	2916 : ClusterShade [NUMERICAL]
# 	2814 : SumAverage [NUMERICAL]
# 	2148 : Imc1 [NUMERICAL]
# 	2045 : Correlation [NUMERICAL]
# 	1995 : InverseVariance [NUMERICAL]
# 	1913 : Imc2 [NUMERICAL]
# 	1906 : Contrast [NUMERICAL]
# 	1885 : DifferenceVariance [NUMERICAL]
# 	1839 : MaximumProbability [NUMERICAL]
# 	1827 : Idm [NUMERICAL]
# 	1775 : DifferenceAverage [NUMERICAL]
# 	1768 : MCC [NUMERICAL]
# 	1725 : Id [NUMERICAL]
# 	1708 : DifferenceEntropy [NUMERICAL]
# 	1691 : SumEntropy [NUMERICAL]
# 	1614 : ClusterProminence [NUMERICAL]
# 	1585 : JointEnergy [NUMERICAL]
# 	1350 : ClusterTendency [NUMERICAL]
# 	1330 : SumSquares [NUMERICAL]
# 	1314 : JointEntropy [NUMERICAL]
#
# Attribute in nodes with depth <= 0:
# 	73 : Autocorrelation [NUMERICAL]
# 	54 : JointAverage [NUMERICAL]
# 	51 : SumAverage [NUMERICAL]
# 	32 : SumEntropy [NUMERICAL]
# 	26 : MCC [NUMERICAL]
# 	18 : Correlation [NUMERICAL]
# 	13 : Imc2 [NUMERICAL]
# 	12 : Imc1 [NUMERICAL]
# 	7 : JointEnergy [NUMERICAL]
# 	5 : JointEntropy [NUMERICAL]
# 	4 : MaximumProbability [NUMERICAL]
# 	2 : Idm [NUMERICAL]
# 	1 : SumSquares [NUMERICAL]
# 	1 : Idmn [NUMERICAL]
# 	1 : Id [NUMERICAL]
#
# Attribute in nodes with depth <= 1:
# 	172 : Autocorrelation [NUMERICAL]
# 	158 : JointAverage [NUMERICAL]
# 	147 : SumAverage [NUMERICAL]
# 	55 : MCC [NUMERICAL]
# 	50 : Correlation [NUMERICAL]
# 	45 : SumEntropy [NUMERICAL]
# 	41 : InverseVariance [NUMERICAL]
# 	41 : Imc1 [NUMERICAL]
# 	31 : MaximumProbability [NUMERICAL]
# 	28 : Imc2 [NUMERICAL]
# 	23 : Id [NUMERICAL]
# 	20 : DifferenceEntropy [NUMERICAL]
# 	18 : JointEnergy [NUMERICAL]
# 	14 : Idm [NUMERICAL]
# 	13 : DifferenceAverage [NUMERICAL]
# 	11 : JointEntropy [NUMERICAL]
# 	8 : Idmn [NUMERICAL]
# 	5 : DifferenceVariance [NUMERICAL]
# 	5 : Contrast [NUMERICAL]
# 	4 : SumSquares [NUMERICAL]
# 	3 : Idn [NUMERICAL]
# 	3 : ClusterShade [NUMERICAL]
# 	2 : ClusterTendency [NUMERICAL]
# 	2 : ClusterProminence [NUMERICAL]
#
# Attribute in nodes with depth <= 2:
# 	333 : Autocorrelation [NUMERICAL]
# 	318 : JointAverage [NUMERICAL]
# 	305 : SumAverage [NUMERICAL]
# 	118 : InverseVariance [NUMERICAL]
# 	105 : Imc1 [NUMERICAL]
# 	101 : MCC [NUMERICAL]
# 	96 : Correlation [NUMERICAL]
# 	86 : SumEntropy [NUMERICAL]
# 	85 : MaximumProbability [NUMERICAL]
# 	73 : Imc2 [NUMERICAL]
# 	62 : JointEnergy [NUMERICAL]
# 	59 : Id [NUMERICAL]
# 	51 : Idm [NUMERICAL]
# 	47 : DifferenceEntropy [NUMERICAL]
# 	42 : DifferenceAverage [NUMERICAL]
# 	32 : ClusterShade [NUMERICAL]
# 	31 : Contrast [NUMERICAL]
# 	26 : JointEntropy [NUMERICAL]
# 	25 : Idmn [NUMERICAL]
# 	21 : DifferenceVariance [NUMERICAL]
# 	18 : SumSquares [NUMERICAL]
# 	15 : Idn [NUMERICAL]
# 	15 : ClusterProminence [NUMERICAL]
# 	13 : ClusterTendency [NUMERICAL]
#
# Attribute in nodes with depth <= 3:
# 	552 : JointAverage [NUMERICAL]
# 	548 : Autocorrelation [NUMERICAL]
# 	524 : SumAverage [NUMERICAL]
# 	210 : InverseVariance [NUMERICAL]
# 	196 : Imc1 [NUMERICAL]
# 	188 : Correlation [NUMERICAL]
# 	174 : MCC [NUMERICAL]
# 	166 : ClusterShade [NUMERICAL]
# 	158 : MaximumProbability [NUMERICAL]
# 	144 : SumEntropy [NUMERICAL]
# 	141 : Idm [NUMERICAL]
# 	141 : Id [NUMERICAL]
# 	138 : Imc2 [NUMERICAL]
# 	115 : JointEnergy [NUMERICAL]
# 	106 : DifferenceEntropy [NUMERICAL]
# 	105 : Idmn [NUMERICAL]
# 	105 : DifferenceAverage [NUMERICAL]
# 	96 : Idn [NUMERICAL]
# 	89 : DifferenceVariance [NUMERICAL]
# 	87 : Contrast [NUMERICAL]
# 	69 : JointEntropy [NUMERICAL]
# 	66 : SumSquares [NUMERICAL]
# 	53 : ClusterProminence [NUMERICAL]
# 	50 : ClusterTendency [NUMERICAL]
#
# Attribute in nodes with depth <= 5:
# 	1110 : Autocorrelation [NUMERICAL]
# 	1073 : JointAverage [NUMERICAL]
# 	1028 : SumAverage [NUMERICAL]
# 	783 : ClusterShade [NUMERICAL]
# 	738 : Idn [NUMERICAL]
# 	706 : Idmn [NUMERICAL]
# 	575 : Correlation [NUMERICAL]
# 	570 : InverseVariance [NUMERICAL]
# 	559 : Imc1 [NUMERICAL]
# 	460 : MaximumProbability [NUMERICAL]
# 	450 : MCC [NUMERICAL]
# 	443 : Idm [NUMERICAL]
# 	418 : Id [NUMERICAL]
# 	416 : Imc2 [NUMERICAL]
# 	410 : SumEntropy [NUMERICAL]
# 	388 : DifferenceAverage [NUMERICAL]
# 	371 : Contrast [NUMERICAL]
# 	370 : DifferenceEntropy [NUMERICAL]
# 	367 : JointEnergy [NUMERICAL]
# 	367 : DifferenceVariance [NUMERICAL]
# 	291 : ClusterProminence [NUMERICAL]
# 	267 : JointEntropy [NUMERICAL]
# 	239 : SumSquares [NUMERICAL]
# 	228 : ClusterTendency [NUMERICAL]
#
# Condition type in nodes:
# 	50731 : HigherCondition
# Condition type in nodes with depth <= 0:
# 	300 : HigherCondition
# Condition type in nodes with depth <= 1:
# 	899 : HigherCondition
# Condition type in nodes with depth <= 2:
# 	2077 : HigherCondition
# Condition type in nodes with depth <= 3:
# 	4221 : HigherCondition
# Condition type in nodes with depth <= 5:
# 	12627 : HigherCondition
# Node format: NOT_SET
#
# Training OOB:
# 	trees: 1, Out-of-bag evaluation: accuracy:0.859377 logloss:5.06857
# 	trees: 11, Out-of-bag evaluation: accuracy:0.881739 logloss:1.41191
# 	trees: 21, Out-of-bag evaluation: accuracy:0.900475 logloss:0.797399
# 	trees: 31, Out-of-bag evaluation: accuracy:0.905415 logloss:0.551863
# 	trees: 41, Out-of-bag evaluation: accuracy:0.908366 logloss:0.456912
# 	trees: 51, Out-of-bag evaluation: accuracy:0.906228 logloss:0.43479
# 	trees: 61, Out-of-bag evaluation: accuracy:0.909416 logloss:0.433552
# 	trees: 71, Out-of-bag evaluation: accuracy:0.908795 logloss:0.416414
# 	trees: 81, Out-of-bag evaluation: accuracy:0.909844 logloss:0.399281
# 	trees: 91, Out-of-bag evaluation: accuracy:0.90996 logloss:0.363639
# 	trees: 101, Out-of-bag evaluation: accuracy:0.9093 logloss:0.363421
# 	trees: 111, Out-of-bag evaluation: accuracy:0.909377 logloss:0.36147
# 	trees: 121, Out-of-bag evaluation: accuracy:0.908443 logloss:0.32593
# 	trees: 131, Out-of-bag evaluation: accuracy:0.908251 logloss:0.308146
# 	trees: 141, Out-of-bag evaluation: accuracy:0.909691 logloss:0.306523
# 	trees: 151, Out-of-bag evaluation: accuracy:0.910312 logloss:0.305948
# 	trees: 161, Out-of-bag evaluation: accuracy:0.909844 logloss:0.305492
# 	trees: 171, Out-of-bag evaluation: accuracy:0.909185 logloss:0.287856
# 	trees: 181, Out-of-bag evaluation: accuracy:0.909691 logloss:0.288966
# 	trees: 191, Out-of-bag evaluation: accuracy:0.909262 logloss:0.288523
# 	trees: 201, Out-of-bag evaluation: accuracy:0.909416 logloss:0.288493
# 	trees: 211, Out-of-bag evaluation: accuracy:0.910388 logloss:0.27121
# 	trees: 221, Out-of-bag evaluation: accuracy:0.91035 logloss:0.270785
# 	trees: 231, Out-of-bag evaluation: accuracy:0.910817 logloss:0.270654
# 	trees: 241, Out-of-bag evaluation: accuracy:0.9114 logloss:0.269927
# 	trees: 251, Out-of-bag evaluation: accuracy:0.910817 logloss:0.269858
# 	trees: 261, Out-of-bag evaluation: accuracy:0.911477 logloss:0.269866
# 	trees: 271, Out-of-bag evaluation: accuracy:0.911438 logloss:0.269911
# 	trees: 281, Out-of-bag evaluation: accuracy:0.911477 logloss:0.269906
# 	trees: 291, Out-of-bag evaluation: accuracy:0.910312 logloss:0.269932
# 	trees: 300, Out-of-bag evaluation: accuracy:0.911477 logloss:0.269914

# %%
# Model features
model.make_inspector().features()
# Out:
# ["Autocorrelation" (1; #0),
#  "ClusterProminence" (1; #1),
#  "ClusterShade" (1; #2),
#  "ClusterTendency" (1; #3),
#  "Contrast" (1; #4),
#  "Correlation" (1; #5),
#  "DifferenceAverage" (1; #6),
#  "DifferenceEntropy" (1; #7),
#  "DifferenceVariance" (1; #8),
#  "Id" (1; #9),
#  "Idm" (1; #10),
#  "Idmn" (1; #11),
#  "Idn" (1; #12),
#  "Imc1" (1; #13),
#  "Imc2" (1; #14),
#  "InverseVariance" (1; #15),
#  "JointAverage" (1; #16),
#  "JointEnergy" (1; #17),
#  "JointEntropy" (1; #18),
#  "MCC" (1; #19),
#  "MaximumProbability" (1; #20),
#  "SumAverage" (1; #21),
#  "SumEntropy" (1; #22),
#  "SumSquares" (1; #23)]

# %%
# Feature importance
model.make_inspector().variable_importances()
# Out:
# {'INV_MEAN_MIN_DEPTH': [("Autocorrelation" (1; #0), 0.18610679543695471),
#   ("JointAverage" (1; #16), 0.1760258849238262),
#   ("SumAverage" (1; #21), 0.16418867152811745),
#   ("InverseVariance" (1; #15), 0.12756019542384844),
#   ("MCC" (1; #19), 0.12526169413628443),
#   ("Imc1" (1; #13), 0.12483898642291724),
#   ("Correlation" (1; #5), 0.1200976188299147),
#   ("MaximumProbability" (1; #20), 0.11800493005264691),
#   ("SumEntropy" (1; #22), 0.11776954366964448),
#   ("Idn" (1; #12), 0.1162945669368041),
#   ("Idmn" (1; #11), 0.11599350965430034),
#   ("Idm" (1; #10), 0.11553315789578536),
#   ("Id" (1; #9), 0.1151152373890382),
#   ("Imc2" (1; #14), 0.11384328305243023),
#   ("ClusterShade" (1; #2), 0.11238583032781387),
#   ("JointEnergy" (1; #17), 0.10860574266609042),
#   ("DifferenceEntropy" (1; #7), 0.10794907642542878),
#   ("DifferenceAverage" (1; #6), 0.10789354103555583),
#   ("Contrast" (1; #4), 0.10551431056014675),
#   ("DifferenceVariance" (1; #8), 0.10443737624219449),
#   ("JointEntropy" (1; #18), 0.10403381209324575),
#   ("ClusterProminence" (1; #1), 0.10298530154114839),
#   ("SumSquares" (1; #23), 0.10195009037492345),
#   ("ClusterTendency" (1; #3), 0.10146097242479996)],
#  'NUM_AS_ROOT': [("Autocorrelation" (1; #0), 73.0),
#   ("JointAverage" (1; #16), 54.0),
#   ("SumAverage" (1; #21), 51.0),
#   ("SumEntropy" (1; #22), 32.0),
#   ("MCC" (1; #19), 26.0),
#   ("Correlation" (1; #5), 18.0),
#   ("Imc2" (1; #14), 13.0),
#   ("Imc1" (1; #13), 12.0),
#   ("JointEnergy" (1; #17), 7.0),
#   ("JointEntropy" (1; #18), 5.0),
#   ("MaximumProbability" (1; #20), 4.0),
#   ("Idm" (1; #10), 2.0),
#   ("Id" (1; #9), 1.0),
#   ("Idmn" (1; #11), 1.0),
#   ("SumSquares" (1; #23), 1.0)],
#  'SUM_SCORE': [("Autocorrelation" (1; #0), 548743.0337725858),
#   ("JointAverage" (1; #16), 477563.1204157022),
#   ("SumAverage" (1; #21), 445937.6427159667),
#   ("Idn" (1; #12), 131806.10666598767),
#   ("Idmn" (1; #11), 118311.51084943888),
#   ("InverseVariance" (1; #15), 105842.61095825103),
#   ("Imc1" (1; #13), 83586.87579635251),
#   ("MaximumProbability" (1; #20), 73754.45421046826),
#   ("MCC" (1; #19), 73473.43544538249),
#   ("SumEntropy" (1; #22), 71481.52233840316),
#   ("Idm" (1; #10), 69626.9520306013),
#   ("ClusterShade" (1; #2), 64865.58373179941),
#   ("Correlation" (1; #5), 64561.67933734662),
#   ("Id" (1; #9), 64477.33562303222),
#   ("Imc2" (1; #14), 60326.80040014916),
#   ("JointEnergy" (1; #17), 51092.747996327125),
#   ("DifferenceAverage" (1; #6), 50994.07780476134),
#   ("Contrast" (1; #4), 46210.68910529143),
#   ("DifferenceEntropy" (1; #7), 45866.44027991245),
#   ("DifferenceVariance" (1; #8), 38876.50657497796),
#   ("JointEntropy" (1; #18), 31513.2539052605),
#   ("ClusterProminence" (1; #1), 30377.24485817441),
#   ("SumSquares" (1; #23), 27218.323184285273),
#   ("ClusterTendency" (1; #3), 25193.12832245364)],
#  'NUM_NODES': [("Idn" (1; #12), 4017.0),
#   ("Idmn" (1; #11), 3577.0),
#   ("Autocorrelation" (1; #0), 3067.0),
#   ("JointAverage" (1; #16), 2922.0),
#   ("ClusterShade" (1; #2), 2916.0),
#   ("SumAverage" (1; #21), 2814.0),
#   ("Imc1" (1; #13), 2148.0),
#   ("Correlation" (1; #5), 2045.0),
#   ("InverseVariance" (1; #15), 1995.0),
#   ("Imc2" (1; #14), 1913.0),
#   ("Contrast" (1; #4), 1906.0),
#   ("DifferenceVariance" (1; #8), 1885.0),
#   ("MaximumProbability" (1; #20), 1839.0),
#   ("Idm" (1; #10), 1827.0),
#   ("DifferenceAverage" (1; #6), 1775.0),
#   ("MCC" (1; #19), 1768.0),
#   ("Id" (1; #9), 1725.0),
#   ("DifferenceEntropy" (1; #7), 1708.0),
#   ("SumEntropy" (1; #22), 1691.0),
#   ("ClusterProminence" (1; #1), 1614.0),
#   ("JointEnergy" (1; #17), 1585.0),
#   ("ClusterTendency" (1; #3), 1350.0),
#   ("SumSquares" (1; #23), 1330.0),
#   ("JointEntropy" (1; #18), 1314.0)]}

# %%
# Model self evaluation
model.make_inspector().evaluation()
# Out:
# Evaluation(num_examples=13938, accuracy=0.9114766227690124, loss=0.2699143503193254, rmse=None, ndcg=None, aucs=None, auuc=None, qini=None)

# %%
logs = model.make_inspector().training_logs()

plt.figure(figsize=(12, 4))
plt.subplot(1, 2, 1)
plt.plot([log.num_trees for log in logs], [log.evaluation.accuracy for log in logs])
plt.xlabel("Number of trees")
plt.ylabel("Accuracy (out-of-bag)")
plt.subplot(1, 2, 2)
plt.plot([log.num_trees for log in logs], [log.evaluation.loss for log in logs])
plt.xlabel("Number of trees")
plt.ylabel("Logloss (out-of-bag)")
plt.show()

# %% [markdown]
# Calculate the score of our hold-out validation dataset

# %%
predictions = model.predict(val_ds)
y_true      = validation_data["label"]

from sklearn.metrics import roc_auc_score
ROC_AUC = roc_auc_score(y_true, predictions)
print("The ROC AUC score is %.5f" % ROC_AUC )
# Out:
# 1/2 [==============>...............] - ETA: 0s
# 2/2 [==============================] - 0s 15ms/step
# The ROC AUC score is 0.99914

# %%
# Compute binary classification metrics with sklearn
import numpy as np
from sklearn.metrics import (
    accuracy_score,
    precision_score,
    recall_score,
    f1_score,
    roc_auc_score,
    average_precision_score,
    confusion_matrix,
    classification_report,
    matthews_corrcoef,
    log_loss,
    brier_score_loss,
)

# Get predictions (probabilities or class labels)
preds = model.predict(test_ds)
# If model outputs probabilities, convert to labels by threshold 0.5
if preds.ndim == 2:
    # For TFDF classification, preds may be class probabilities with shape (N, 2)
    if preds.shape[1] == 2:
        pos_probs = preds[:, 1]
    else:
        # If single-probability column (positive class)
        pos_probs = preds[:, -1]
    y_pred = (pos_probs >= 0.5).astype(int)
else:
    # Already class labels
    y_pred = preds.astype(int)
    pos_probs = None

# Ground truth labels (must be 0/1 integers)
y_true = test_data["label"].astype(int).to_numpy()

# Core metrics
metrics = {}
metrics["accuracy"] = accuracy_score(y_true, y_pred)
metrics["precision"] = precision_score(y_true, y_pred, zero_division=0)
metrics["recall"] = recall_score(y_true, y_pred, zero_division=0)
metrics["f1"] = f1_score(y_true, y_pred, zero_division=0)
metrics["mcc"] = matthews_corrcoef(y_true, y_pred)

# Probabilistic metrics (only if we have probabilities)
if pos_probs is not None:
    metrics["roc_auc"] = roc_auc_score(y_true, pos_probs)
    metrics["pr_auc"] = average_precision_score(y_true, pos_probs)
    metrics["log_loss"] = log_loss(y_true, pos_probs, labels=[0,1])
    metrics["brier_score"] = brier_score_loss(y_true, pos_probs)

# Confusion matrix and detailed report
cm = confusion_matrix(y_true, y_pred, labels=[0,1])
report = classification_report(y_true, y_pred, digits=4)

print("Sklearn binary metrics:")
for k, v in metrics.items():
    print(f"{k}: {v:.4f}")
print("\nConfusion matrix:\n", cm)
print("\nClassification report:\n", report)
# Out:
# 1/5 [=====>........................] - ETA: 0s
# 5/5 [==============================] - ETA: 0s
# 5/5 [==============================] - 0s 13ms/step
# Sklearn binary metrics:
# accuracy: 0.9655
# precision: 0.8464
# recall: 0.7927
# f1: 0.8186
# mcc: 0.8001
# roc_auc: 0.9784
# pr_auc: 0.8982
# log_loss: 0.1005
# brier_score: 0.0259
#
# Confusion matrix:
#  [[3710   59]
#  [  85  325]]
#
# Classification report:
#                precision    recall  f1-score   support
#
#            0     0.9776    0.9843    0.9810      3769
#            1     0.8464    0.7927    0.8186       410
#
#     accuracy                         0.9655      4179
#    macro avg     0.9120    0.8885    0.8998      4179
# weighted avg     0.9647    0.9655    0.9650      4179
