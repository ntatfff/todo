# %%
# Import packages and modules
import numpy  as np
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow_decision_forests as tfdf

from sklearn.model_selection import train_test_split
# Out:
# 2026-09-11 08:23:52.253266: I tensorflow/core/util/port.cc:113] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2026-09-11 08:23:52.294232: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2026-09-11 08:23:56.559142: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
# Check the version of TensorFlow Decision Forests
print("Found TensorFlow Decision Forests v" + tfdf.__version__)
# Out:
# Found TensorFlow Decision Forests v1.9.1

# %%
datasetPath = "dataset/10p/all/kernel3/"

# %%
# Parameters
datasetPath = "dataset/10p/glcm/kernel5/"

# %%
# train/validation/test = 70/10/20
train_data = pd.read_csv(f"{datasetPath}dataset.train.csv")
validation_data = pd.read_csv(f"{datasetPath}dataset.validation.csv")
test_data = pd.read_csv(f"{datasetPath}dataset.test.csv")

# %%
from sklearn.utils.class_weight import compute_class_weight

# tinh class weight tren tap train
classes = np.array([0, 1])
weights = compute_class_weight(class_weight="balanced", classes=classes, y=train_data["label"])
class_weight = {0: weights[0], 1: weights[1]}

# gan sample_weight cho tung dong
train_data["sample_weight"] = train_data["label"].map(class_weight)
validation_data["sample_weight"] = validation_data["label"].map(class_weight)
test_data["sample_weight"] = test_data["label"].map(class_weight)

# Convert the dataset into a TensorFlow dataset.
train_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    train_data, label="label", weight="sample_weight"
)         
val_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    validation_data, label="label", weight="sample_weight"
)
test_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    test_data, label="label", weight="sample_weight"
)
# Out:
# 2026-09-11 08:24:08.286324: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:984] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2026-09-11 08:24:08.287744: W tensorflow/core/common_runtime/gpu/gpu_device.cc:2251] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...

# %%
import keras

# %%
# %%time

# Train a Random Forest model.
model = tfdf.keras.RandomForestModel()

# Add evaluation metrics
model.compile(
    metrics=["accuracy"]
)
model.fit(x=train_ds)

# # Train a Gradient Boosted Trees model.
# model = tfdf.keras.GradientBoostedTreesModel(num_trees=1500)
# model.fit(train_ds)
# Out:
# Use /tmp/tmpna1vbc0y as temporary training directory
# Reading training dataset...
# Training dataset read in 0:00:02.576949. Found 7617 examples.
# Training model...
# Model trained in 0:00:00.485517
# Compiling model...
# [INFO 26-09-11 08:24:11.4193 UTC kernel.cc:1233] Loading model from path /tmp/tmpna1vbc0y/model/ with prefix 923504fb04a544ce
# [INFO 26-09-11 08:24:11.4900 UTC decision_forest.cc:734] Model loaded with 300 root(s), 63580 node(s), and 24 input feature(s).
# [INFO 26-09-11 08:24:11.4901 UTC abstract_model.cc:1362] Engine "RandomForestOptPred" built
# [INFO 26-09-11 08:24:11.4901 UTC kernel.cc:1061] Use fast generic engine
# Model compiled.
# CPU times: user 9.43 s, sys: 142 ms, total: 9.57 s
# Wall time: 6.13 s

# %%
# Evaluate the model
evaluate = model.evaluate(val_ds, return_dict=True)
print()

for name, value in evaluate.items():
    print(f"{name}: {value:.4f}")
# Out:
# WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 1/2 [==============>...............] - ETA: 3s - loss: 0.0000e+00 - accuracy: 0.9900
# 2/2 [==============================] - 4s 8ms/step - loss: 0.0000e+00 - accuracy: 0.9898
# loss: 0.0000
# accuracy: 0.9898

# %%
# Model Summary
model.summary()
# Out:
# Model: "random_forest_model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
# =================================================================
# Total params: 1 (1.00 Byte)
# Trainable params: 0 (0.00 Byte)
# Non-trainable params: 1 (1.00 Byte)
# _________________________________________________________________
# Type: "RANDOM_FOREST"
# Task: CLASSIFICATION
# Label: "__LABEL"
#
# Input Features (24):
# 	Autocorrelation
# 	ClusterProminence
# 	ClusterShade
# 	ClusterTendency
# 	Contrast
# 	Correlation
# 	DifferenceAverage
# 	DifferenceEntropy
# 	DifferenceVariance
# 	Id
# 	Idm
# 	Idmn
# 	Idn
# 	Imc1
# 	Imc2
# 	InverseVariance
# 	JointAverage
# 	JointEnergy
# 	JointEntropy
# 	MCC
# 	MaximumProbability
# 	SumAverage
# 	SumEntropy
# 	SumSquares
#
# Trained with weights
#
# Variable Importance: INV_MEAN_MIN_DEPTH:
#     1.    "Autocorrelation"  0.179105 ################
#     2.       "JointAverage"  0.177921 ###############
#     3.         "SumAverage"  0.175960 ###############
#     4.               "Imc1"  0.157149 ##########
#     5.    "InverseVariance"  0.141146 #######
#     6.         "SumEntropy"  0.130295 ####
#     7.                "MCC"  0.130146 ####
#     8.        "Correlation"  0.127263 ####
#     9.               "Imc2"  0.123734 ###
#    10.                "Idm"  0.121290 ##
#    11.                "Idn"  0.120959 ##
#    12. "MaximumProbability"  0.120618 ##
#    13.       "ClusterShade"  0.119987 ##
#    14.                 "Id"  0.118904 ##
#    15.               "Idmn"  0.118889 ##
#    16.        "JointEnergy"  0.118237 ##
#    17. "DifferenceVariance"  0.115240 #
#    18.  "DifferenceAverage"  0.114551 #
#    19.  "DifferenceEntropy"  0.114364 #
#    20.           "Contrast"  0.113882 #
#    21.       "JointEntropy"  0.113098
#    22.  "ClusterProminence"  0.111988
#    23.    "ClusterTendency"  0.109731
#    24.         "SumSquares"  0.109337
#
# Variable Importance: NUM_AS_ROOT:
#     1.    "Autocorrelation" 65.000000 ################
#     2.       "JointAverage" 58.000000 ##############
#     3.         "SumAverage" 57.000000 ##############
#     4.         "SumEntropy" 38.000000 #########
#     5.               "Imc1" 26.000000 ######
#     6.                "MCC" 16.000000 ###
#     7.        "Correlation" 12.000000 ##
#     8.               "Imc2"  9.000000 ##
#     9.       "JointEntropy"  9.000000 ##
#    10.        "JointEnergy"  7.000000 #
#    11. "MaximumProbability"  2.000000
#    12.  "ClusterProminence"  1.000000
#
# Variable Importance: NUM_NODES:
#     1.                "Idn" 2253.000000 ################
#     2.               "Idmn" 2039.000000 #############
#     3.    "Autocorrelation" 1980.000000 ############
#     4.       "JointAverage" 1967.000000 ############
#     5.       "ClusterShade" 1947.000000 ############
#     6.         "SumAverage" 1935.000000 ############
#     7.               "Imc1" 1468.000000 #######
#     8.    "InverseVariance" 1249.000000 ####
#     9.               "Imc2" 1226.000000 ####
#    10.        "Correlation" 1224.000000 ####
#    11.         "SumEntropy" 1182.000000 ####
#    12. "DifferenceVariance" 1163.000000 ###
#    13.                "Idm" 1133.000000 ###
#    14.           "Contrast" 1126.000000 ###
#    15.                "MCC" 1112.000000 ###
#    16. "MaximumProbability" 1097.000000 ###
#    17.  "ClusterProminence" 1038.000000 ##
#    18.  "DifferenceEntropy" 1020.000000 ##
#    19.  "DifferenceAverage" 1006.000000 ##
#    20.                 "Id" 995.000000 ##
#    21.        "JointEnergy" 970.000000 #
#    22.       "JointEntropy" 869.000000
#    23.         "SumSquares" 839.000000
#    24.    "ClusterTendency" 802.000000
#
# Variable Importance: SUM_SCORE:
#     1.    "Autocorrelation" 261266.524955 ################
#     2.       "JointAverage" 254471.764319 ###############
#     3.         "SumAverage" 246044.220957 ###############
#     4.               "Imc1" 76805.296174 ####
#     5.    "InverseVariance" 66194.399693 ###
#     6.                "Idn" 59373.864119 ##
#     7.         "SumEntropy" 53990.009445 ##
#     8.               "Idmn" 51274.352360 ##
#     9.               "Imc2" 41643.819853 #
#    10.                "MCC" 41220.407227 #
#    11.                "Idm" 39116.852756 #
#    12.       "ClusterShade" 38246.196794 #
#    13.        "Correlation" 36988.942983 #
#    14. "MaximumProbability" 34407.279911 #
#    15.                 "Id" 31364.671084 #
#    16.        "JointEnergy" 30465.492514 #
#    17.  "DifferenceAverage" 25197.458537
#    18.  "DifferenceEntropy" 24125.183450
#    19.           "Contrast" 23764.076427
#    20. "DifferenceVariance" 22357.483257
#    21.       "JointEntropy" 20478.782645
#    22.  "ClusterProminence" 18533.594674
#    23.    "ClusterTendency" 16175.360847
#    24.         "SumSquares" 14423.749108
#
#
#
# Winner takes all: true
# Out-of-bag evaluation: accuracy:0.884496 logloss:0.251005
# Number of trees: 300
# Total number of nodes: 63580
#
# Number of nodes by tree:
# Count: 300 Average: 211.933 StdDev: 14.776
# Min: 175 Max: 261 Ignored: 0
# ----------------------------------------------
# [ 175, 179)  1   0.33%   0.33%
# [ 179, 183)  1   0.33%   0.67%
# [ 183, 188)  8   2.67%   3.33% ##
# [ 188, 192) 13   4.33%   7.67% ###
# [ 192, 196) 17   5.67%  13.33% ###
# [ 196, 201) 22   7.33%  20.67% ####
# [ 201, 205) 35  11.67%  32.33% #######
# [ 205, 209) 30  10.00%  42.33% ######
# [ 209, 214) 50  16.67%  59.00% ##########
# [ 214, 218) 27   9.00%  68.00% #####
# [ 218, 222) 28   9.33%  77.33% ######
# [ 222, 227) 18   6.00%  83.33% ####
# [ 227, 231) 18   6.00%  89.33% ####
# [ 231, 235)  9   3.00%  92.33% ##
# [ 235, 240) 11   3.67%  96.00% ##
# [ 240, 244)  4   1.33%  97.33% #
# [ 244, 248)  3   1.00%  98.33% #
# [ 248, 253)  1   0.33%  98.67%
# [ 253, 257)  1   0.33%  99.00%
# [ 257, 261]  3   1.00% 100.00% #
#
# Depth by leafs:
# Count: 31940 Average: 8.5923 StdDev: 2.49359
# Min: 2 Max: 15 Ignored: 0
# ----------------------------------------------
# [  2,  3)   46   0.14%   0.14%
# [  3,  4)  305   0.95%   1.10% #
# [  4,  5) 1066   3.34%   4.44% ##
# [  5,  6) 2064   6.46%  10.90% ####
# [  6,  7) 3319  10.39%  21.29% #######
# [  7,  8) 4246  13.29%  34.58% #########
# [  8,  9) 4787  14.99%  49.57% ##########
# [  9, 10) 4764  14.92%  64.49% ##########
# [ 10, 11) 4078  12.77%  77.25% #########
# [ 11, 12) 3153   9.87%  87.13% #######
# [ 12, 13) 2096   6.56%  93.69% ####
# [ 13, 14) 1104   3.46%  97.14% ##
# [ 14, 15)  608   1.90%  99.05% #
# [ 15, 15]  304   0.95% 100.00% #
#
# Number of training obs by leaf:
# Count: 31940 Average: 71.5435 StdDev: 229.208
# Min: 5 Max: 2754 Ignored: 0
# ----------------------------------------------
# [    5,  142) 28860  90.36%  90.36% ##########
# [  142,  280)  1167   3.65%  94.01%
# [  280,  417)   548   1.72%  95.73%
# [  417,  555)   320   1.00%  96.73%
# [  555,  692)   259   0.81%  97.54%
# [  692,  830)   181   0.57%  98.11%
# [  830,  967)   121   0.38%  98.48%
# [  967, 1105)    91   0.28%  98.77%
# [ 1105, 1242)    79   0.25%  99.02%
# [ 1242, 1380)    45   0.14%  99.16%
# [ 1380, 1517)    39   0.12%  99.28%
# [ 1517, 1655)    20   0.06%  99.34%
# [ 1655, 1792)    37   0.12%  99.46%
# [ 1792, 1930)    38   0.12%  99.58%
# [ 1930, 2067)    36   0.11%  99.69%
# [ 2067, 2205)    38   0.12%  99.81%
# [ 2205, 2342)    27   0.08%  99.89%
# [ 2342, 2480)    18   0.06%  99.95%
# [ 2480, 2617)    10   0.03%  99.98%
# [ 2617, 2754]     6   0.02% 100.00%
#
# Attribute in nodes:
# 	2253 : Idn [NUMERICAL]
# 	2039 : Idmn [NUMERICAL]
# 	1980 : Autocorrelation [NUMERICAL]
# 	1967 : JointAverage [NUMERICAL]
# 	1947 : ClusterShade [NUMERICAL]
# 	1935 : SumAverage [NUMERICAL]
# 	1468 : Imc1 [NUMERICAL]
# 	1249 : InverseVariance [NUMERICAL]
# 	1226 : Imc2 [NUMERICAL]
# 	1224 : Correlation [NUMERICAL]
# 	1182 : SumEntropy [NUMERICAL]
# 	1163 : DifferenceVariance [NUMERICAL]
# 	1133 : Idm [NUMERICAL]
# 	1126 : Contrast [NUMERICAL]
# 	1112 : MCC [NUMERICAL]
# 	1097 : MaximumProbability [NUMERICAL]
# 	1038 : ClusterProminence [NUMERICAL]
# 	1020 : DifferenceEntropy [NUMERICAL]
# 	1006 : DifferenceAverage [NUMERICAL]
# 	995 : Id [NUMERICAL]
# 	970 : JointEnergy [NUMERICAL]
# 	869 : JointEntropy [NUMERICAL]
# 	839 : SumSquares [NUMERICAL]
# 	802 : ClusterTendency [NUMERICAL]
#
# Attribute in nodes with depth <= 0:
# 	65 : Autocorrelation [NUMERICAL]
# 	58 : JointAverage [NUMERICAL]
# 	57 : SumAverage [NUMERICAL]
# 	38 : SumEntropy [NUMERICAL]
# 	26 : Imc1 [NUMERICAL]
# 	16 : MCC [NUMERICAL]
# 	12 : Correlation [NUMERICAL]
# 	9 : JointEntropy [NUMERICAL]
# 	9 : Imc2 [NUMERICAL]
# 	7 : JointEnergy [NUMERICAL]
# 	2 : MaximumProbability [NUMERICAL]
# 	1 : ClusterProminence [NUMERICAL]
#
# Attribute in nodes with depth <= 1:
# 	169 : Autocorrelation [NUMERICAL]
# 	163 : JointAverage [NUMERICAL]
# 	158 : SumAverage [NUMERICAL]
# 	87 : Imc1 [NUMERICAL]
# 	57 : MCC [NUMERICAL]
# 	48 : SumEntropy [NUMERICAL]
# 	45 : Correlation [NUMERICAL]
# 	37 : InverseVariance [NUMERICAL]
# 	23 : JointEnergy [NUMERICAL]
# 	23 : Imc2 [NUMERICAL]
# 	22 : MaximumProbability [NUMERICAL]
# 	14 : JointEntropy [NUMERICAL]
# 	9 : ClusterShade [NUMERICAL]
# 	8 : Idm [NUMERICAL]
# 	7 : DifferenceVariance [NUMERICAL]
# 	7 : Contrast [NUMERICAL]
# 	6 : Id [NUMERICAL]
# 	5 : DifferenceAverage [NUMERICAL]
# 	4 : DifferenceEntropy [NUMERICAL]
# 	3 : Idmn [NUMERICAL]
# 	2 : ClusterProminence [NUMERICAL]
# 	1 : SumSquares [NUMERICAL]
# 	1 : Idn [NUMERICAL]
# 	1 : ClusterTendency [NUMERICAL]
#
# Attribute in nodes with depth <= 2:
# 	306 : JointAverage [NUMERICAL]
# 	298 : Autocorrelation [NUMERICAL]
# 	297 : SumAverage [NUMERICAL]
# 	159 : Imc1 [NUMERICAL]
# 	128 : InverseVariance [NUMERICAL]
# 	108 : Correlation [NUMERICAL]
# 	97 : MCC [NUMERICAL]
# 	71 : SumEntropy [NUMERICAL]
# 	71 : ClusterShade [NUMERICAL]
# 	63 : Idm [NUMERICAL]
# 	60 : MaximumProbability [NUMERICAL]
# 	60 : JointEnergy [NUMERICAL]
# 	60 : Imc2 [NUMERICAL]
# 	51 : Id [NUMERICAL]
# 	37 : DifferenceVariance [NUMERICAL]
# 	37 : DifferenceAverage [NUMERICAL]
# 	29 : DifferenceEntropy [NUMERICAL]
# 	27 : Contrast [NUMERICAL]
# 	25 : JointEntropy [NUMERICAL]
# 	17 : ClusterProminence [NUMERICAL]
# 	15 : SumSquares [NUMERICAL]
# 	14 : ClusterTendency [NUMERICAL]
# 	13 : Idn [NUMERICAL]
# 	11 : Idmn [NUMERICAL]
#
# Attribute in nodes with depth <= 3:
# 	493 : JointAverage [NUMERICAL]
# 	484 : SumAverage [NUMERICAL]
# 	470 : Autocorrelation [NUMERICAL]
# 	270 : Imc1 [NUMERICAL]
# 	240 : InverseVariance [NUMERICAL]
# 	209 : ClusterShade [NUMERICAL]
# 	180 : Correlation [NUMERICAL]
# 	165 : Imc2 [NUMERICAL]
# 	159 : MCC [NUMERICAL]
# 	141 : SumEntropy [NUMERICAL]
# 	138 : Idm [NUMERICAL]
# 	129 : MaximumProbability [NUMERICAL]
# 	116 : JointEnergy [NUMERICAL]
# 	115 : Id [NUMERICAL]
# 	112 : DifferenceVariance [NUMERICAL]
# 	97 : DifferenceAverage [NUMERICAL]
# 	87 : Idn [NUMERICAL]
# 	81 : Contrast [NUMERICAL]
# 	75 : ClusterProminence [NUMERICAL]
# 	72 : DifferenceEntropy [NUMERICAL]
# 	65 : JointEntropy [NUMERICAL]
# 	61 : Idmn [NUMERICAL]
# 	49 : SumSquares [NUMERICAL]
# 	49 : ClusterTendency [NUMERICAL]
#
# Attribute in nodes with depth <= 5:
# 	925 : JointAverage [NUMERICAL]
# 	924 : Autocorrelation [NUMERICAL]
# 	864 : SumAverage [NUMERICAL]
# 	730 : ClusterShade [NUMERICAL]
# 	575 : Imc1 [NUMERICAL]
# 	573 : Idn [NUMERICAL]
# 	532 : InverseVariance [NUMERICAL]
# 	516 : Idmn [NUMERICAL]
# 	437 : Imc2 [NUMERICAL]
# 	422 : Correlation [NUMERICAL]
# 	400 : MCC [NUMERICAL]
# 	391 : Idm [NUMERICAL]
# 	388 : DifferenceVariance [NUMERICAL]
# 	373 : SumEntropy [NUMERICAL]
# 	335 : MaximumProbability [NUMERICAL]
# 	331 : Id [NUMERICAL]
# 	319 : Contrast [NUMERICAL]
# 	310 : JointEnergy [NUMERICAL]
# 	289 : DifferenceAverage [NUMERICAL]
# 	282 : ClusterProminence [NUMERICAL]
# 	258 : DifferenceEntropy [NUMERICAL]
# 	222 : JointEntropy [NUMERICAL]
# 	212 : SumSquares [NUMERICAL]
# 	205 : ClusterTendency [NUMERICAL]
#
# Condition type in nodes:
# 	31640 : HigherCondition
# Condition type in nodes with depth <= 0:
# 	300 : HigherCondition
# Condition type in nodes with depth <= 1:
# 	900 : HigherCondition
# Condition type in nodes with depth <= 2:
# 	2054 : HigherCondition
# Condition type in nodes with depth <= 3:
# 	4057 : HigherCondition
# Condition type in nodes with depth <= 5:
# 	10813 : HigherCondition
# Node format: NOT_SET
#
# Training OOB:
# 	trees: 1, Out-of-bag evaluation: accuracy:0.840295 logloss:5.75634
# 	trees: 11, Out-of-bag evaluation: accuracy:0.851808 logloss:1.73576
# 	trees: 21, Out-of-bag evaluation: accuracy:0.869228 logloss:1.02458
# 	trees: 32, Out-of-bag evaluation: accuracy:0.873131 logloss:0.73987
# 	trees: 42, Out-of-bag evaluation: accuracy:0.878233 logloss:0.488755
# 	trees: 52, Out-of-bag evaluation: accuracy:0.883195 logloss:0.449814
# 	trees: 62, Out-of-bag evaluation: accuracy:0.887136 logloss:0.419688
# 	trees: 72, Out-of-bag evaluation: accuracy:0.883195 logloss:0.387343
# 	trees: 82, Out-of-bag evaluation: accuracy:0.881014 logloss:0.351795
# 	trees: 92, Out-of-bag evaluation: accuracy:0.882985 logloss:0.283072
# 	trees: 102, Out-of-bag evaluation: accuracy:0.882914 logloss:0.28296
# 	trees: 112, Out-of-bag evaluation: accuracy:0.884075 logloss:0.249107
# 	trees: 122, Out-of-bag evaluation: accuracy:0.882914 logloss:0.249189
# 	trees: 132, Out-of-bag evaluation: accuracy:0.881964 logloss:0.252098
# 	trees: 142, Out-of-bag evaluation: accuracy:0.884145 logloss:0.251818
# 	trees: 152, Out-of-bag evaluation: accuracy:0.883055 logloss:0.252712
# 	trees: 162, Out-of-bag evaluation: accuracy:0.881154 logloss:0.253361
# 	trees: 172, Out-of-bag evaluation: accuracy:0.883265 logloss:0.251868
# 	trees: 182, Out-of-bag evaluation: accuracy:0.883265 logloss:0.251916
# 	trees: 192, Out-of-bag evaluation: accuracy:0.880344 logloss:0.252632
# 	trees: 202, Out-of-bag evaluation: accuracy:0.881224 logloss:0.251918
# 	trees: 212, Out-of-bag evaluation: accuracy:0.880204 logloss:0.25297
# 	trees: 222, Out-of-bag evaluation: accuracy:0.886186 logloss:0.25185
# 	trees: 232, Out-of-bag evaluation: accuracy:0.885166 logloss:0.251832
# 	trees: 242, Out-of-bag evaluation: accuracy:0.886186 logloss:0.251702
# 	trees: 252, Out-of-bag evaluation: accuracy:0.885236 logloss:0.251517
# 	trees: 262, Out-of-bag evaluation: accuracy:0.884075 logloss:0.251412
# 	trees: 272, Out-of-bag evaluation: accuracy:0.887347 logloss:0.251254
# 	trees: 282, Out-of-bag evaluation: accuracy:0.887417 logloss:0.251448
# 	trees: 292, Out-of-bag evaluation: accuracy:0.885657 logloss:0.251871
# 	trees: 300, Out-of-bag evaluation: accuracy:0.884496 logloss:0.251005

# %%
# Model features
model.make_inspector().features()
# Out:
# ["Autocorrelation" (1; #0),
#  "ClusterProminence" (1; #1),
#  "ClusterShade" (1; #2),
#  "ClusterTendency" (1; #3),
#  "Contrast" (1; #4),
#  "Correlation" (1; #5),
#  "DifferenceAverage" (1; #6),
#  "DifferenceEntropy" (1; #7),
#  "DifferenceVariance" (1; #8),
#  "Id" (1; #9),
#  "Idm" (1; #10),
#  "Idmn" (1; #11),
#  "Idn" (1; #12),
#  "Imc1" (1; #13),
#  "Imc2" (1; #14),
#  "InverseVariance" (1; #15),
#  "JointAverage" (1; #16),
#  "JointEnergy" (1; #17),
#  "JointEntropy" (1; #18),
#  "MCC" (1; #19),
#  "MaximumProbability" (1; #20),
#  "SumAverage" (1; #21),
#  "SumEntropy" (1; #22),
#  "SumSquares" (1; #23)]

# %%
# Feature importance
model.make_inspector().variable_importances()
# Out:
# {'INV_MEAN_MIN_DEPTH': [("Autocorrelation" (1; #0), 0.17910494084160894),
#   ("JointAverage" (1; #16), 0.17792050745379767),
#   ("SumAverage" (1; #21), 0.1759600688873105),
#   ("Imc1" (1; #13), 0.15714883057379606),
#   ("InverseVariance" (1; #15), 0.14114586852160624),
#   ("SumEntropy" (1; #22), 0.1302951193827941),
#   ("MCC" (1; #19), 0.1301463126974777),
#   ("Correlation" (1; #5), 0.12726322586043792),
#   ("Imc2" (1; #14), 0.123734040434379),
#   ("Idm" (1; #10), 0.1212897218576534),
#   ("Idn" (1; #12), 0.12095897565132108),
#   ("MaximumProbability" (1; #20), 0.12061764645442549),
#   ("ClusterShade" (1; #2), 0.11998661717944316),
#   ("Id" (1; #9), 0.11890408598386712),
#   ("Idmn" (1; #11), 0.11888905682639356),
#   ("JointEnergy" (1; #17), 0.11823680238596902),
#   ("DifferenceVariance" (1; #8), 0.1152398736527819),
#   ("DifferenceAverage" (1; #6), 0.11455077910363008),
#   ("DifferenceEntropy" (1; #7), 0.11436355798652384),
#   ("Contrast" (1; #4), 0.11388193675208494),
#   ("JointEntropy" (1; #18), 0.11309767949012069),
#   ("ClusterProminence" (1; #1), 0.11198785196658309),
#   ("ClusterTendency" (1; #3), 0.10973149820921123),
#   ("SumSquares" (1; #23), 0.10933748296436059)],
#  'SUM_SCORE': [("Autocorrelation" (1; #0), 261266.5249550183),
#   ("JointAverage" (1; #16), 254471.76431920382),
#   ("SumAverage" (1; #21), 246044.22095651962),
#   ("Imc1" (1; #13), 76805.29617437557),
#   ("InverseVariance" (1; #15), 66194.39969256215),
#   ("Idn" (1; #12), 59373.86411942791),
#   ("SumEntropy" (1; #22), 53990.00944473307),
#   ("Idmn" (1; #11), 51274.35236048144),
#   ("Imc2" (1; #14), 41643.81985296618),
#   ("MCC" (1; #19), 41220.40722731707),
#   ("Idm" (1; #10), 39116.85275569137),
#   ("ClusterShade" (1; #2), 38246.19679414994),
#   ("Correlation" (1; #5), 36988.942983104906),
#   ("MaximumProbability" (1; #20), 34407.279910686055),
#   ("Id" (1; #9), 31364.671083694422),
#   ("JointEnergy" (1; #17), 30465.492514025493),
#   ("DifferenceAverage" (1; #6), 25197.458536779486),
#   ("DifferenceEntropy" (1; #7), 24125.183450334214),
#   ("Contrast" (1; #4), 23764.0764271963),
#   ("DifferenceVariance" (1; #8), 22357.48325722889),
#   ("JointEntropy" (1; #18), 20478.782644902778),
#   ("ClusterProminence" (1; #1), 18533.594674223972),
#   ("ClusterTendency" (1; #3), 16175.36084746694),
#   ("SumSquares" (1; #23), 14423.749108311416)],
#  'NUM_AS_ROOT': [("Autocorrelation" (1; #0), 65.0),
#   ("JointAverage" (1; #16), 58.0),
#   ("SumAverage" (1; #21), 57.0),
#   ("SumEntropy" (1; #22), 38.0),
#   ("Imc1" (1; #13), 26.0),
#   ("MCC" (1; #19), 16.0),
#   ("Correlation" (1; #5), 12.0),
#   ("Imc2" (1; #14), 9.0),
#   ("JointEntropy" (1; #18), 9.0),
#   ("JointEnergy" (1; #17), 7.0),
#   ("MaximumProbability" (1; #20), 2.0),
#   ("ClusterProminence" (1; #1), 1.0)],
#  'NUM_NODES': [("Idn" (1; #12), 2253.0),
#   ("Idmn" (1; #11), 2039.0),
#   ("Autocorrelation" (1; #0), 1980.0),
#   ("JointAverage" (1; #16), 1967.0),
#   ("ClusterShade" (1; #2), 1947.0),
#   ("SumAverage" (1; #21), 1935.0),
#   ("Imc1" (1; #13), 1468.0),
#   ("InverseVariance" (1; #15), 1249.0),
#   ("Imc2" (1; #14), 1226.0),
#   ("Correlation" (1; #5), 1224.0),
#   ("SumEntropy" (1; #22), 1182.0),
#   ("DifferenceVariance" (1; #8), 1163.0),
#   ("Idm" (1; #10), 1133.0),
#   ("Contrast" (1; #4), 1126.0),
#   ("MCC" (1; #19), 1112.0),
#   ("MaximumProbability" (1; #20), 1097.0),
#   ("ClusterProminence" (1; #1), 1038.0),
#   ("DifferenceEntropy" (1; #7), 1020.0),
#   ("DifferenceAverage" (1; #6), 1006.0),
#   ("Id" (1; #9), 995.0),
#   ("JointEnergy" (1; #17), 970.0),
#   ("JointEntropy" (1; #18), 869.0),
#   ("SumSquares" (1; #23), 839.0),
#   ("ClusterTendency" (1; #3), 802.0)]}

# %%
# Model self evaluation
model.make_inspector().evaluation()
# Out:
# Evaluation(num_examples=7617, accuracy=0.884496010239381, loss=0.25100507128662614, rmse=None, ndcg=None, aucs=None, auuc=None, qini=None)

# %%
logs = model.make_inspector().training_logs()

plt.figure(figsize=(12, 4))
plt.subplot(1, 2, 1)
plt.plot([log.num_trees for log in logs], [log.evaluation.accuracy for log in logs])
plt.xlabel("Number of trees")
plt.ylabel("Accuracy (out-of-bag)")
plt.subplot(1, 2, 2)
plt.plot([log.num_trees for log in logs], [log.evaluation.loss for log in logs])
plt.xlabel("Number of trees")
plt.ylabel("Logloss (out-of-bag)")
plt.show()

# %% [markdown]
# Calculate the score of our hold-out validation dataset

# %%
predictions = model.predict(val_ds)
y_true      = validation_data["label"]

from sklearn.metrics import roc_auc_score
ROC_AUC = roc_auc_score(y_true, predictions)
print("The ROC AUC score is %.5f" % ROC_AUC )
# Out:
# 1/2 [==============>...............] - ETA: 0s
# 2/2 [==============================] - 0s 3ms/step
# The ROC AUC score is 0.99894

# %%
# Compute binary classification metrics with sklearn
import numpy as np
from sklearn.metrics import (
    accuracy_score,
    precision_score,
    recall_score,
    f1_score,
    roc_auc_score,
    average_precision_score,
    confusion_matrix,
    classification_report,
    matthews_corrcoef,
    log_loss,
    brier_score_loss,
)

# Get predictions (probabilities or class labels)
preds = model.predict(test_ds)
# If model outputs probabilities, convert to labels by threshold 0.5
if preds.ndim == 2:
    # For TFDF classification, preds may be class probabilities with shape (N, 2)
    if preds.shape[1] == 2:
        pos_probs = preds[:, 1]
    else:
        # If single-probability column (positive class)
        pos_probs = preds[:, -1]
    y_pred = (pos_probs >= 0.5).astype(int)
else:
    # Already class labels
    y_pred = preds.astype(int)
    pos_probs = None

# Ground truth labels (must be 0/1 integers)
y_true = test_data["label"].astype(int).to_numpy()

# Core metrics
metrics = {}
metrics["accuracy"] = accuracy_score(y_true, y_pred)
metrics["precision"] = precision_score(y_true, y_pred, zero_division=0)
metrics["recall"] = recall_score(y_true, y_pred, zero_division=0)
metrics["f1"] = f1_score(y_true, y_pred, zero_division=0)
metrics["mcc"] = matthews_corrcoef(y_true, y_pred)

# Probabilistic metrics (only if we have probabilities)
if pos_probs is not None:
    metrics["roc_auc"] = roc_auc_score(y_true, pos_probs)
    metrics["pr_auc"] = average_precision_score(y_true, pos_probs)
    metrics["log_loss"] = log_loss(y_true, pos_probs, labels=[0,1])
    metrics["brier_score"] = brier_score_loss(y_true, pos_probs)

# Confusion matrix and detailed report
cm = confusion_matrix(y_true, y_pred, labels=[0,1])
report = classification_report(y_true, y_pred, digits=4)

print("Sklearn binary metrics:")
for k, v in metrics.items():
    print(f"{k}: {v:.4f}")
print("\nConfusion matrix:\n", cm)
print("\nClassification report:\n", report)
# Out:
# 1/3 [=========>....................] - ETA: 0s
# 3/3 [==============================] - 0s 8ms/step
# Sklearn binary metrics:
# accuracy: 0.9650
# precision: 0.8621
# recall: 0.7709
# f1: 0.8140
# mcc: 0.7962
# roc_auc: 0.9793
# pr_auc: 0.9012
# log_loss: 0.1003
# brier_score: 0.0259
#
# Confusion matrix:
#  [[2028   28]
#  [  52  175]]
#
# Classification report:
#                precision    recall  f1-score   support
#
#            0     0.9750    0.9864    0.9807      2056
#            1     0.8621    0.7709    0.8140       227
#
#     accuracy                         0.9650      2283
#    macro avg     0.9185    0.8787    0.8973      2283
# weighted avg     0.9638    0.9650    0.9641      2283
