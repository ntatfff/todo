# %%
# Import packages and modules
import numpy  as np
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow_decision_forests as tfdf

from sklearn.model_selection import train_test_split
# Out:
# 2026-09-11 08:17:27.123975: I tensorflow/core/util/port.cc:113] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2026-09-11 08:17:27.165058: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2026-09-11 08:17:32.566960: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
# Check the version of TensorFlow Decision Forests
print("Found TensorFlow Decision Forests v" + tfdf.__version__)
# Out:
# Found TensorFlow Decision Forests v1.9.1

# %%
datasetPath = "dataset/10p/all/kernel3/"

# %%
# Parameters
datasetPath = "dataset/10p/glszm/kernel5/"

# %%
# train/validation/test = 70/10/20
train_data = pd.read_csv(f"{datasetPath}dataset.train.csv")
validation_data = pd.read_csv(f"{datasetPath}dataset.validation.csv")
test_data = pd.read_csv(f"{datasetPath}dataset.test.csv")

# %%
from sklearn.utils.class_weight import compute_class_weight

# tinh class weight tren tap train
classes = np.array([0, 1])
weights = compute_class_weight(class_weight="balanced", classes=classes, y=train_data["label"])
class_weight = {0: weights[0], 1: weights[1]}

# gan sample_weight cho tung dong
train_data["sample_weight"] = train_data["label"].map(class_weight)
validation_data["sample_weight"] = validation_data["label"].map(class_weight)
test_data["sample_weight"] = test_data["label"].map(class_weight)

# Convert the dataset into a TensorFlow dataset.
train_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    train_data, label="label", weight="sample_weight"
)         
val_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    validation_data, label="label", weight="sample_weight"
)
test_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    test_data, label="label", weight="sample_weight"
)
# Out:
# 2026-09-11 08:17:44.372390: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:984] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2026-09-11 08:17:44.374084: W tensorflow/core/common_runtime/gpu/gpu_device.cc:2251] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...

# %%
import keras

# %%
# %%time

# Train a Gradient Boosted Trees model.
model = tfdf.keras.GradientBoostedTreesModel()

# Add evaluation metrics
model.compile(
    metrics=["accuracy"]
)
model.fit(x=train_ds)

# # Train a Gradient Boosted Trees model.
# model = tfdf.keras.GradientBoostedTreesModel(num_trees=1500)
# model.fit(train_ds)
# Out:
# Use /tmp/tmpk865it4i as temporary training directory
# Reading training dataset...
# [WARNING 26-09-11 08:17:44.4933 UTC gradient_boosted_trees.cc:1840] "goss_alpha" set but "sampling_method" not equal to "GOSS".
# [WARNING 26-09-11 08:17:44.4934 UTC gradient_boosted_trees.cc:1851] "goss_beta" set but "sampling_method" not equal to "GOSS".
# [WARNING 26-09-11 08:17:44.4934 UTC gradient_boosted_trees.cc:1865] "selective_gradient_boosting_ratio" set but "sampling_method" not equal to "SELGB".
# Training dataset read in 0:00:02.472092. Found 7617 examples.
# Training model...
# Model trained in 0:00:00.666249
# Compiling model...
# [INFO 26-09-11 08:17:47.6535 UTC kernel.cc:1233] Loading model from path /tmp/tmpk865it4i/model/ with prefix 9622991916064aa5
# [INFO 26-09-11 08:17:47.6558 UTC quick_scorer_extended.cc:911] The binary was compiled without AVX2 support, but your CPU supports it. Enable it for faster model inference.
# [INFO 26-09-11 08:17:47.6560 UTC abstract_model.cc:1362] Engine "GradientBoostedTreesQuickScorerExtended" built
# [INFO 26-09-11 08:17:47.6560 UTC kernel.cc:1061] Use fast generic engine
# Model compiled.
# CPU times: user 7.89 s, sys: 431 ms, total: 8.32 s
# Wall time: 6.16 s

# %%
# Evaluate the model
evaluate = model.evaluate(val_ds, return_dict=True)
print()

for name, value in evaluate.items():
    print(f"{name}: {value:.4f}")
# Out:
# WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 1/2 [==============>...............] - ETA: 2s - loss: 0.0000e+00 - accuracy: 0.9730
# 2/2 [==============================] - 3s 8ms/step - loss: 0.0000e+00 - accuracy: 0.9712
# loss: 0.0000
# accuracy: 0.9712

# %%
# Model Summary
model.summary()
# Out:
# Model: "gradient_boosted_trees_model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
# =================================================================
# Total params: 1 (1.00 Byte)
# Trainable params: 0 (0.00 Byte)
# Non-trainable params: 1 (1.00 Byte)
# _________________________________________________________________
# Type: "GRADIENT_BOOSTED_TREES"
# Task: CLASSIFICATION
# Label: "__LABEL"
#
# Input Features (16):
# 	GrayLevelNonUniformity
# 	GrayLevelNonUniformityNormalized
# 	GrayLevelVariance
# 	HighGrayLevelZoneEmphasis
# 	LargeAreaEmphasis
# 	LargeAreaHighGrayLevelEmphasis
# 	LargeAreaLowGrayLevelEmphasis
# 	LowGrayLevelZoneEmphasis
# 	SizeZoneNonUniformity
# 	SizeZoneNonUniformityNormalized
# 	SmallAreaEmphasis
# 	SmallAreaHighGrayLevelEmphasis
# 	SmallAreaLowGrayLevelEmphasis
# 	ZoneEntropy
# 	ZonePercentage
# 	ZoneVariance
#
# Trained with weights
#
# Variable Importance: INV_MEAN_MIN_DEPTH:
#     1.        "HighGrayLevelZoneEmphasis"  0.511724 ################
#     2.   "LargeAreaHighGrayLevelEmphasis"  0.239294 ###
#     3.           "GrayLevelNonUniformity"  0.223519 ##
#     4.    "LargeAreaLowGrayLevelEmphasis"  0.216998 ##
#     5.                      "ZoneEntropy"  0.194640
#     6.         "LowGrayLevelZoneEmphasis"  0.188429
#     7.   "SmallAreaHighGrayLevelEmphasis"  0.188043
#     8. "GrayLevelNonUniformityNormalized"  0.187021
#     9.                "SmallAreaEmphasis"  0.180624
#    10.                "GrayLevelVariance"  0.180356
#    11.    "SmallAreaLowGrayLevelEmphasis"  0.178221
#    12.                     "ZoneVariance"  0.178098
#    13.  "SizeZoneNonUniformityNormalized"  0.176215
#    14.                   "ZonePercentage"  0.175977
#    15.            "SizeZoneNonUniformity"  0.174413
#    16.                "LargeAreaEmphasis"  0.174338
#
# Variable Importance: NUM_AS_ROOT:
#     1.       "HighGrayLevelZoneEmphasis" 37.000000 ################
#     2.  "LargeAreaHighGrayLevelEmphasis"  4.000000 #
#     3.          "GrayLevelNonUniformity"  2.000000
#     4.               "SmallAreaEmphasis"  2.000000
#     5.   "LargeAreaLowGrayLevelEmphasis"  1.000000
#     6.        "LowGrayLevelZoneEmphasis"  1.000000
#     7. "SizeZoneNonUniformityNormalized"  1.000000
#
# Variable Importance: NUM_NODES:
#     1.        "HighGrayLevelZoneEmphasis" 199.000000 ################
#     2.    "LargeAreaLowGrayLevelEmphasis" 148.000000 ###########
#     3.           "GrayLevelNonUniformity" 136.000000 ##########
#     4.   "LargeAreaHighGrayLevelEmphasis" 126.000000 #########
#     5.                      "ZoneEntropy" 100.000000 #######
#     6.   "SmallAreaHighGrayLevelEmphasis" 95.000000 ######
#     7.         "LowGrayLevelZoneEmphasis" 72.000000 ####
#     8. "GrayLevelNonUniformityNormalized" 69.000000 ####
#     9.                "GrayLevelVariance" 56.000000 ###
#    10.    "SmallAreaLowGrayLevelEmphasis" 44.000000 ##
#    11.                     "ZoneVariance" 38.000000 ##
#    12.                "LargeAreaEmphasis" 34.000000 #
#    13.                   "ZonePercentage" 26.000000
#    14.            "SizeZoneNonUniformity" 25.000000
#    15.                "SmallAreaEmphasis" 22.000000
#    16.  "SizeZoneNonUniformityNormalized" 15.000000
#
# Variable Importance: SUM_SCORE:
#     1.        "HighGrayLevelZoneEmphasis" 4675.223674 ################
#     2.           "GrayLevelNonUniformity" 788.942793 ##
#     3.   "LargeAreaHighGrayLevelEmphasis" 731.631203 ##
#     4.    "LargeAreaLowGrayLevelEmphasis" 565.227712 #
#     5.                      "ZoneEntropy" 406.952346 #
#     6.   "SmallAreaHighGrayLevelEmphasis" 303.792231
#     7. "GrayLevelNonUniformityNormalized" 186.567189
#     8.         "LowGrayLevelZoneEmphasis" 165.075285
#     9.                "LargeAreaEmphasis" 121.804507
#    10.                     "ZoneVariance" 74.425086
#    11.    "SmallAreaLowGrayLevelEmphasis" 73.031763
#    12.                "GrayLevelVariance" 70.180083
#    13.            "SizeZoneNonUniformity" 49.859172
#    14.  "SizeZoneNonUniformityNormalized" 36.868920
#    15.                   "ZonePercentage" 33.642274
#    16.                "SmallAreaEmphasis" 17.787219
#
#
#
# Loss: BINOMIAL_LOG_LIKELIHOOD
# Validation loss value: 0.386973
# Number of trees per iteration: 1
# Node format: NOT_SET
# Number of trees: 48
# Total number of nodes: 2458
#
# Number of nodes by tree:
# Count: 48 Average: 51.2083 StdDev: 4.97057
# Min: 41 Max: 61 Ignored: 0
# ----------------------------------------------
# [ 41, 42)  2   4.17%   4.17% ##
# [ 42, 43)  0   0.00%   4.17%
# [ 43, 44)  0   0.00%   4.17%
# [ 44, 45)  0   0.00%   4.17%
# [ 45, 46)  3   6.25%  10.42% ###
# [ 46, 47)  0   0.00%  10.42%
# [ 47, 48) 11  22.92%  33.33% ##########
# [ 48, 49)  0   0.00%  33.33%
# [ 49, 50)  6  12.50%  45.83% #####
# [ 50, 51)  0   0.00%  45.83%
# [ 51, 52)  5  10.42%  56.25% #####
# [ 52, 53)  0   0.00%  56.25%
# [ 53, 54)  7  14.58%  70.83% ######
# [ 54, 55)  0   0.00%  70.83%
# [ 55, 56)  5  10.42%  81.25% #####
# [ 56, 57)  0   0.00%  81.25%
# [ 57, 58)  4   8.33%  89.58% ####
# [ 58, 59)  0   0.00%  89.58%
# [ 59, 60)  2   4.17%  93.75% ##
# [ 60, 61]  3   6.25% 100.00% ###
#
# Depth by leafs:
# Count: 1253 Average: 4.83001 StdDev: 0.496429
# Min: 2 Max: 5 Ignored: 0
# ----------------------------------------------
# [ 2, 3)    4   0.32%   0.32%
# [ 3, 4)   54   4.31%   4.63%
# [ 4, 5)   93   7.42%  12.05% #
# [ 5, 5] 1102  87.95% 100.00% ##########
#
# Number of training obs by leaf:
# Count: 1253 Average: 263.138 StdDev: 669.161
# Min: 5 Max: 5913 Ignored: 0
# ----------------------------------------------
# [    5,  300) 1051  83.88%  83.88% ##########
# [  300,  595)   75   5.99%  89.86% #
# [  595,  891)   28   2.23%  92.10%
# [  891, 1186)   10   0.80%  92.90%
# [ 1186, 1482)   12   0.96%  93.85%
# [ 1482, 1777)   14   1.12%  94.97%
# [ 1777, 2073)   15   1.20%  96.17%
# [ 2073, 2368)   16   1.28%  97.45%
# [ 2368, 2664)    7   0.56%  98.00%
# [ 2664, 2959)    3   0.24%  98.24%
# [ 2959, 3254)    7   0.56%  98.80%
# [ 3254, 3550)    3   0.24%  99.04%
# [ 3550, 3845)    2   0.16%  99.20%
# [ 3845, 4141)    2   0.16%  99.36%
# [ 4141, 4436)    2   0.16%  99.52%
# [ 4436, 4732)    1   0.08%  99.60%
# [ 4732, 5027)    4   0.32%  99.92%
# [ 5027, 5323)    0   0.00%  99.92%
# [ 5323, 5618)    0   0.00%  99.92%
# [ 5618, 5913]    1   0.08% 100.00%
#
# Attribute in nodes:
# 	199 : HighGrayLevelZoneEmphasis [NUMERICAL]
# 	148 : LargeAreaLowGrayLevelEmphasis [NUMERICAL]
# 	136 : GrayLevelNonUniformity [NUMERICAL]
# 	126 : LargeAreaHighGrayLevelEmphasis [NUMERICAL]
# 	100 : ZoneEntropy [NUMERICAL]
# 	95 : SmallAreaHighGrayLevelEmphasis [NUMERICAL]
# 	72 : LowGrayLevelZoneEmphasis [NUMERICAL]
# 	69 : GrayLevelNonUniformityNormalized [NUMERICAL]
# 	56 : GrayLevelVariance [NUMERICAL]
# 	44 : SmallAreaLowGrayLevelEmphasis [NUMERICAL]
# 	38 : ZoneVariance [NUMERICAL]
# 	34 : LargeAreaEmphasis [NUMERICAL]
# 	26 : ZonePercentage [NUMERICAL]
# 	25 : SizeZoneNonUniformity [NUMERICAL]
# 	22 : SmallAreaEmphasis [NUMERICAL]
# 	15 : SizeZoneNonUniformityNormalized [NUMERICAL]
#
# Attribute in nodes with depth <= 0:
# 	37 : HighGrayLevelZoneEmphasis [NUMERICAL]
# 	4 : LargeAreaHighGrayLevelEmphasis [NUMERICAL]
# 	2 : SmallAreaEmphasis [NUMERICAL]
# 	2 : GrayLevelNonUniformity [NUMERICAL]
# 	1 : SizeZoneNonUniformityNormalized [NUMERICAL]
# 	1 : LowGrayLevelZoneEmphasis [NUMERICAL]
# 	1 : LargeAreaLowGrayLevelEmphasis [NUMERICAL]
#
# Attribute in nodes with depth <= 1:
# 	59 : HighGrayLevelZoneEmphasis [NUMERICAL]
# 	28 : LargeAreaHighGrayLevelEmphasis [NUMERICAL]
# 	18 : GrayLevelNonUniformity [NUMERICAL]
# 	14 : LargeAreaLowGrayLevelEmphasis [NUMERICAL]
# 	5 : SmallAreaEmphasis [NUMERICAL]
# 	5 : LowGrayLevelZoneEmphasis [NUMERICAL]
# 	4 : SmallAreaHighGrayLevelEmphasis [NUMERICAL]
# 	3 : ZoneEntropy [NUMERICAL]
# 	3 : GrayLevelVariance [NUMERICAL]
# 	2 : SmallAreaLowGrayLevelEmphasis [NUMERICAL]
# 	2 : GrayLevelNonUniformityNormalized [NUMERICAL]
# 	1 : SizeZoneNonUniformityNormalized [NUMERICAL]
#
# Attribute in nodes with depth <= 2:
# 	80 : HighGrayLevelZoneEmphasis [NUMERICAL]
# 	52 : LargeAreaLowGrayLevelEmphasis [NUMERICAL]
# 	43 : GrayLevelNonUniformity [NUMERICAL]
# 	35 : ZoneEntropy [NUMERICAL]
# 	35 : LargeAreaHighGrayLevelEmphasis [NUMERICAL]
# 	20 : GrayLevelNonUniformityNormalized [NUMERICAL]
# 	14 : LowGrayLevelZoneEmphasis [NUMERICAL]
# 	12 : ZoneVariance [NUMERICAL]
# 	10 : SmallAreaHighGrayLevelEmphasis [NUMERICAL]
# 	10 : SmallAreaEmphasis [NUMERICAL]
# 	10 : GrayLevelVariance [NUMERICAL]
# 	4 : ZonePercentage [NUMERICAL]
# 	4 : SmallAreaLowGrayLevelEmphasis [NUMERICAL]
# 	2 : SizeZoneNonUniformityNormalized [NUMERICAL]
# 	1 : SizeZoneNonUniformity [NUMERICAL]
#
# Attribute in nodes with depth <= 3:
# 	130 : HighGrayLevelZoneEmphasis [NUMERICAL]
# 	84 : LargeAreaLowGrayLevelEmphasis [NUMERICAL]
# 	71 : GrayLevelNonUniformity [NUMERICAL]
# 	70 : LargeAreaHighGrayLevelEmphasis [NUMERICAL]
# 	61 : ZoneEntropy [NUMERICAL]
# 	44 : SmallAreaHighGrayLevelEmphasis [NUMERICAL]
# 	41 : GrayLevelNonUniformityNormalized [NUMERICAL]
# 	34 : LowGrayLevelZoneEmphasis [NUMERICAL]
# 	30 : GrayLevelVariance [NUMERICAL]
# 	19 : SmallAreaLowGrayLevelEmphasis [NUMERICAL]
# 	18 : ZoneVariance [NUMERICAL]
# 	16 : SmallAreaEmphasis [NUMERICAL]
# 	13 : ZonePercentage [NUMERICAL]
# 	11 : SizeZoneNonUniformity [NUMERICAL]
# 	7 : LargeAreaEmphasis [NUMERICAL]
# 	5 : SizeZoneNonUniformityNormalized [NUMERICAL]
#
# Attribute in nodes with depth <= 5:
# 	199 : HighGrayLevelZoneEmphasis [NUMERICAL]
# 	148 : LargeAreaLowGrayLevelEmphasis [NUMERICAL]
# 	136 : GrayLevelNonUniformity [NUMERICAL]
# 	126 : LargeAreaHighGrayLevelEmphasis [NUMERICAL]
# 	100 : ZoneEntropy [NUMERICAL]
# 	95 : SmallAreaHighGrayLevelEmphasis [NUMERICAL]
# 	72 : LowGrayLevelZoneEmphasis [NUMERICAL]
# 	69 : GrayLevelNonUniformityNormalized [NUMERICAL]
# 	56 : GrayLevelVariance [NUMERICAL]
# 	44 : SmallAreaLowGrayLevelEmphasis [NUMERICAL]
# 	38 : ZoneVariance [NUMERICAL]
# 	34 : LargeAreaEmphasis [NUMERICAL]
# 	26 : ZonePercentage [NUMERICAL]
# 	25 : SizeZoneNonUniformity [NUMERICAL]
# 	22 : SmallAreaEmphasis [NUMERICAL]
# 	15 : SizeZoneNonUniformityNormalized [NUMERICAL]
#
# Condition type in nodes:
# 	1205 : HigherCondition
# Condition type in nodes with depth <= 0:
# 	48 : HigherCondition
# Condition type in nodes with depth <= 1:
# 	144 : HigherCondition
# Condition type in nodes with depth <= 2:
# 	332 : HigherCondition
# Condition type in nodes with depth <= 3:
# 	654 : HigherCondition
# Condition type in nodes with depth <= 5:
# 	1205 : HigherCondition
#
# Training logs:
# Number of iteration to final model: 48
# 	Iter:1 train-loss:1.252363 valid-loss:1.244993  train-accuracy:0.902838 valid-accuracy:0.928666
# 	Iter:2 train-loss:1.142389 valid-loss:1.131799  train-accuracy:0.905377 valid-accuracy:0.931446
# 	Iter:3 train-loss:1.050278 valid-loss:1.039059  train-accuracy:0.908896 valid-accuracy:0.920642
# 	Iter:4 train-loss:0.971432 valid-loss:0.961187  train-accuracy:0.912223 valid-accuracy:0.921337
# 	Iter:5 train-loss:0.899553 valid-loss:0.888460  train-accuracy:0.913003 valid-accuracy:0.924812
# 	Iter:6 train-loss:0.838337 valid-loss:0.830164  train-accuracy:0.915110 valid-accuracy:0.926202
# 	Iter:16 train-loss:0.485515 valid-loss:0.523107  train-accuracy:0.941534 valid-accuracy:0.935933
# 	Iter:26 train-loss:0.340823 valid-loss:0.413157  train-accuracy:0.956395 valid-accuracy:0.930689
# 	Iter:36 train-loss:0.268663 valid-loss:0.393747  train-accuracy:0.969731 valid-accuracy:0.932774
# 	Iter:46 train-loss:0.221768 valid-loss:0.393466  train-accuracy:0.976257 valid-accuracy:0.932079
# 	Iter:56 train-loss:0.184381 valid-loss:0.411192  train-accuracy:0.982315 valid-accuracy:0.922665
# 	Iter:66 train-loss:0.159393 valid-loss:0.420745  train-accuracy:0.986536 valid-accuracy:0.922665
# 	Iter:76 train-loss:0.140866 valid-loss:0.425471  train-accuracy:0.987394 valid-accuracy:0.916031

# %%
# Model features
model.make_inspector().features()
# Out:
# ["GrayLevelNonUniformity" (1; #0),
#  "GrayLevelNonUniformityNormalized" (1; #1),
#  "GrayLevelVariance" (1; #2),
#  "HighGrayLevelZoneEmphasis" (1; #3),
#  "LargeAreaEmphasis" (1; #4),
#  "LargeAreaHighGrayLevelEmphasis" (1; #5),
#  "LargeAreaLowGrayLevelEmphasis" (1; #6),
#  "LowGrayLevelZoneEmphasis" (1; #7),
#  "SizeZoneNonUniformity" (1; #8),
#  "SizeZoneNonUniformityNormalized" (1; #9),
#  "SmallAreaEmphasis" (1; #10),
#  "SmallAreaHighGrayLevelEmphasis" (1; #11),
#  "SmallAreaLowGrayLevelEmphasis" (1; #12),
#  "ZoneEntropy" (1; #13),
#  "ZonePercentage" (1; #14),
#  "ZoneVariance" (1; #15)]

# %%
# Feature importance
model.make_inspector().variable_importances()
# Out:
# {'INV_MEAN_MIN_DEPTH': [("HighGrayLevelZoneEmphasis" (1; #3),
#    0.5117242734847691),
#   ("LargeAreaHighGrayLevelEmphasis" (1; #5), 0.23929427427160316),
#   ("GrayLevelNonUniformity" (1; #0), 0.22351850067079349),
#   ("LargeAreaLowGrayLevelEmphasis" (1; #6), 0.21699750340166785),
#   ("ZoneEntropy" (1; #13), 0.19464026006046334),
#   ("LowGrayLevelZoneEmphasis" (1; #7), 0.18842905875610955),
#   ("SmallAreaHighGrayLevelEmphasis" (1; #11), 0.18804288575834066),
#   ("GrayLevelNonUniformityNormalized" (1; #1), 0.1870207243077553),
#   ("SmallAreaEmphasis" (1; #10), 0.1806242504854536),
#   ("GrayLevelVariance" (1; #2), 0.1803559641624168),
#   ("SmallAreaLowGrayLevelEmphasis" (1; #12), 0.1782212594680041),
#   ("ZoneVariance" (1; #15), 0.17809762520088138),
#   ("SizeZoneNonUniformityNormalized" (1; #9), 0.17621525304322277),
#   ("ZonePercentage" (1; #14), 0.17597719953183433),
#   ("SizeZoneNonUniformity" (1; #8), 0.17441296407853724),
#   ("LargeAreaEmphasis" (1; #4), 0.17433842145131037)],
#  'NUM_AS_ROOT': [("HighGrayLevelZoneEmphasis" (1; #3), 37.0),
#   ("LargeAreaHighGrayLevelEmphasis" (1; #5), 4.0),
#   ("GrayLevelNonUniformity" (1; #0), 2.0),
#   ("SmallAreaEmphasis" (1; #10), 2.0),
#   ("LargeAreaLowGrayLevelEmphasis" (1; #6), 1.0),
#   ("LowGrayLevelZoneEmphasis" (1; #7), 1.0),
#   ("SizeZoneNonUniformityNormalized" (1; #9), 1.0)],
#  'SUM_SCORE': [("HighGrayLevelZoneEmphasis" (1; #3), 4675.223673954092),
#   ("GrayLevelNonUniformity" (1; #0), 788.9427927210152),
#   ("LargeAreaHighGrayLevelEmphasis" (1; #5), 731.6312031271297),
#   ("LargeAreaLowGrayLevelEmphasis" (1; #6), 565.2277117667528),
#   ("ZoneEntropy" (1; #13), 406.9523462598757),
#   ("SmallAreaHighGrayLevelEmphasis" (1; #11), 303.79223067385533),
#   ("GrayLevelNonUniformityNormalized" (1; #1), 186.5671892505242),
#   ("LowGrayLevelZoneEmphasis" (1; #7), 165.0752845985603),
#   ("LargeAreaEmphasis" (1; #4), 121.80450688805955),
#   ("ZoneVariance" (1; #15), 74.42508562027366),
#   ("SmallAreaLowGrayLevelEmphasis" (1; #12), 73.03176303479127),
#   ("GrayLevelVariance" (1; #2), 70.18008280516788),
#   ("SizeZoneNonUniformity" (1; #8), 49.85917239533393),
#   ("SizeZoneNonUniformityNormalized" (1; #9), 36.86892048387915),
#   ("ZonePercentage" (1; #14), 33.642273596220676),
#   ("SmallAreaEmphasis" (1; #10), 17.787219122602817)],
#  'NUM_NODES': [("HighGrayLevelZoneEmphasis" (1; #3), 199.0),
#   ("LargeAreaLowGrayLevelEmphasis" (1; #6), 148.0),
#   ("GrayLevelNonUniformity" (1; #0), 136.0),
#   ("LargeAreaHighGrayLevelEmphasis" (1; #5), 126.0),
#   ("ZoneEntropy" (1; #13), 100.0),
#   ("SmallAreaHighGrayLevelEmphasis" (1; #11), 95.0),
#   ("LowGrayLevelZoneEmphasis" (1; #7), 72.0),
#   ("GrayLevelNonUniformityNormalized" (1; #1), 69.0),
#   ("GrayLevelVariance" (1; #2), 56.0),
#   ("SmallAreaLowGrayLevelEmphasis" (1; #12), 44.0),
#   ("ZoneVariance" (1; #15), 38.0),
#   ("LargeAreaEmphasis" (1; #4), 34.0),
#   ("ZonePercentage" (1; #14), 26.0),
#   ("SizeZoneNonUniformity" (1; #8), 25.0),
#   ("SmallAreaEmphasis" (1; #10), 22.0),
#   ("SizeZoneNonUniformityNormalized" (1; #9), 15.0)]}

# %%
# Model self evaluation
model.make_inspector().evaluation()
# Out:
# Evaluation(num_examples=None, accuracy=0.9212745428085327, loss=0.386973112821579, rmse=None, ndcg=None, aucs=None, auuc=None, qini=None)

# %%
logs = model.make_inspector().training_logs()

plt.figure(figsize=(12, 4))
plt.subplot(1, 2, 1)
plt.plot([log.num_trees for log in logs], [log.evaluation.accuracy for log in logs])
plt.xlabel("Number of trees")
plt.ylabel("Accuracy (out-of-bag)")
plt.subplot(1, 2, 2)
plt.plot([log.num_trees for log in logs], [log.evaluation.loss for log in logs])
plt.xlabel("Number of trees")
plt.ylabel("Logloss (out-of-bag)")
plt.show()

# %% [markdown]
# Calculate the score of our hold-out validation dataset

# %%
predictions = model.predict(val_ds)
y_true      = validation_data["label"]

from sklearn.metrics import roc_auc_score
ROC_AUC = roc_auc_score(y_true, predictions)
print("The ROC AUC score is %.5f" % ROC_AUC )
# Out:
# 1/2 [==============>...............] - ETA: 0s
# 2/2 [==============================] - 0s 3ms/step
# The ROC AUC score is 0.99625

# %%
# Compute binary classification metrics with sklearn
import numpy as np
from sklearn.metrics import (
    accuracy_score,
    precision_score,
    recall_score,
    f1_score,
    roc_auc_score,
    average_precision_score,
    confusion_matrix,
    classification_report,
    matthews_corrcoef,
    log_loss,
    brier_score_loss,
)

# Get predictions (probabilities or class labels)
preds = model.predict(test_ds)
# If model outputs probabilities, convert to labels by threshold 0.5
if preds.ndim == 2:
    # For TFDF classification, preds may be class probabilities with shape (N, 2)
    if preds.shape[1] == 2:
        pos_probs = preds[:, 1]
    else:
        # If single-probability column (positive class)
        pos_probs = preds[:, -1]
    y_pred = (pos_probs >= 0.5).astype(int)
else:
    # Already class labels
    y_pred = preds.astype(int)
    pos_probs = None

# Ground truth labels (must be 0/1 integers)
y_true = test_data["label"].astype(int).to_numpy()

# Core metrics
metrics = {}
metrics["accuracy"] = accuracy_score(y_true, y_pred)
metrics["precision"] = precision_score(y_true, y_pred, zero_division=0)
metrics["recall"] = recall_score(y_true, y_pred, zero_division=0)
metrics["f1"] = f1_score(y_true, y_pred, zero_division=0)
metrics["mcc"] = matthews_corrcoef(y_true, y_pred)

# Probabilistic metrics (only if we have probabilities)
if pos_probs is not None:
    metrics["roc_auc"] = roc_auc_score(y_true, pos_probs)
    metrics["pr_auc"] = average_precision_score(y_true, pos_probs)
    metrics["log_loss"] = log_loss(y_true, pos_probs, labels=[0,1])
    metrics["brier_score"] = brier_score_loss(y_true, pos_probs)

# Confusion matrix and detailed report
cm = confusion_matrix(y_true, y_pred, labels=[0,1])
report = classification_report(y_true, y_pred, digits=4)

print("Sklearn binary metrics:")
for k, v in metrics.items():
    print(f"{k}: {v:.4f}")
print("\nConfusion matrix:\n", cm)
print("\nClassification report:\n", report)
# Out:
# 1/3 [=========>....................] - ETA: 0s
# 3/3 [==============================] - 0s 3ms/step
# Sklearn binary metrics:
# accuracy: 0.9488
# precision: 0.7371
# recall: 0.7533
# f1: 0.7451
# mcc: 0.7167
# roc_auc: 0.9653
# pr_auc: 0.8427
# log_loss: 0.1417
# brier_score: 0.0384
#
# Confusion matrix:
#  [[1995   61]
#  [  56  171]]
#
# Classification report:
#                precision    recall  f1-score   support
#
#            0     0.9727    0.9703    0.9715      2056
#            1     0.7371    0.7533    0.7451       227
#
#     accuracy                         0.9488      2283
#    macro avg     0.8549    0.8618    0.8583      2283
# weighted avg     0.9493    0.9488    0.9490      2283
