# %%
# Import packages and modules
import numpy  as np
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow_decision_forests as tfdf

from sklearn.model_selection import train_test_split
# Out:
# 2026-09-11 08:18:00.904592: I tensorflow/core/util/port.cc:113] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2026-09-11 08:18:00.944445: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2026-09-11 08:18:06.251818: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
# Check the version of TensorFlow Decision Forests
print("Found TensorFlow Decision Forests v" + tfdf.__version__)
# Out:
# Found TensorFlow Decision Forests v1.9.1

# %%
datasetPath = "dataset/10p/all/kernel3/"

# %%
# Parameters
datasetPath = "dataset/10p/ngtdm/kernel5/"

# %%
# train/validation/test = 70/10/20
train_data = pd.read_csv(f"{datasetPath}dataset.train.csv")
validation_data = pd.read_csv(f"{datasetPath}dataset.validation.csv")
test_data = pd.read_csv(f"{datasetPath}dataset.test.csv")

# %%
from sklearn.utils.class_weight import compute_class_weight

# tinh class weight tren tap train
classes = np.array([0, 1])
weights = compute_class_weight(class_weight="balanced", classes=classes, y=train_data["label"])
class_weight = {0: weights[0], 1: weights[1]}

# gan sample_weight cho tung dong
train_data["sample_weight"] = train_data["label"].map(class_weight)
validation_data["sample_weight"] = validation_data["label"].map(class_weight)
test_data["sample_weight"] = test_data["label"].map(class_weight)

# Convert the dataset into a TensorFlow dataset.
train_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    train_data, label="label", weight="sample_weight"
)         
val_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    validation_data, label="label", weight="sample_weight"
)
test_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    test_data, label="label", weight="sample_weight"
)
# Out:
# 2026-09-11 08:18:18.073755: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:984] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2026-09-11 08:18:18.074962: W tensorflow/core/common_runtime/gpu/gpu_device.cc:2251] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...

# %%
import keras

# %%
# %%time

# Train a Gradient Boosted Trees model.
model = tfdf.keras.GradientBoostedTreesModel()

# Add evaluation metrics
model.compile(
    metrics=["accuracy"]
)
model.fit(x=train_ds)

# # Train a Gradient Boosted Trees model.
# model = tfdf.keras.GradientBoostedTreesModel(num_trees=1500)
# model.fit(train_ds)
# Out:
# Use /tmp/tmp20w1hrdx as temporary training directory
# Reading training dataset...
# [WARNING 26-09-11 08:18:18.1698 UTC gradient_boosted_trees.cc:1840] "goss_alpha" set but "sampling_method" not equal to "GOSS".
# [WARNING 26-09-11 08:18:18.1699 UTC gradient_boosted_trees.cc:1851] "goss_beta" set but "sampling_method" not equal to "GOSS".
# [WARNING 26-09-11 08:18:18.1699 UTC gradient_boosted_trees.cc:1865] "selective_gradient_boosting_ratio" set but "sampling_method" not equal to "SELGB".
# Training dataset read in 0:00:02.361172. Found 7617 examples.
# Training model...
# Model trained in 0:00:00.423590
# Compiling model...
# [INFO 26-09-11 08:18:20.9749 UTC kernel.cc:1233] Loading model from path /tmp/tmp20w1hrdx/model/ with prefix b6293428abae4f76
# [INFO 26-09-11 08:18:20.9775 UTC quick_scorer_extended.cc:911] The binary was compiled without AVX2 support, but your CPU supports it. Enable it for faster model inference.
# [INFO 26-09-11 08:18:20.9777 UTC abstract_model.cc:1362] Engine "GradientBoostedTreesQuickScorerExtended" built
# [INFO 26-09-11 08:18:20.9777 UTC kernel.cc:1061] Use fast generic engine
# Model compiled.
# CPU times: user 6.04 s, sys: 209 ms, total: 6.24 s
# Wall time: 5.78 s

# %%
# Evaluate the model
evaluate = model.evaluate(val_ds, return_dict=True)
print()

for name, value in evaluate.items():
    print(f"{name}: {value:.4f}")
# Out:
# WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 1/2 [==============>...............] - ETA: 2s - loss: 0.0000e+00 - accuracy: 0.9410
# 2/2 [==============================] - 3s 7ms/step - loss: 0.0000e+00 - accuracy: 0.9387
# loss: 0.0000
# accuracy: 0.9387

# %%
# Model Summary
model.summary()
# Out:
# Model: "gradient_boosted_trees_model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
# =================================================================
# Total params: 1 (1.00 Byte)
# Trainable params: 0 (0.00 Byte)
# Non-trainable params: 1 (1.00 Byte)
# _________________________________________________________________
# Type: "GRADIENT_BOOSTED_TREES"
# Task: CLASSIFICATION
# Label: "__LABEL"
#
# Input Features (5):
# 	Busyness
# 	Coarseness
# 	Complexity
# 	Contrast
# 	Strength
#
# Trained with weights
#
# Variable Importance: INV_MEAN_MIN_DEPTH:
#     1.   "Busyness"  0.810063 ################
#     2. "Coarseness"  0.259609 #
#     3. "Complexity"  0.235872
#     4.   "Strength"  0.216748
#     5.   "Contrast"  0.201905
#
# Variable Importance: NUM_AS_ROOT:
#     1.   "Busyness" 43.000000 ################
#     2. "Coarseness"  5.000000
#
# Variable Importance: NUM_NODES:
#     1.   "Busyness" 392.000000 ################
#     2. "Complexity" 227.000000 ####
#     3.   "Strength" 219.000000 ####
#     4. "Coarseness" 203.000000 ###
#     5.   "Contrast" 159.000000
#
# Variable Importance: SUM_SCORE:
#     1.   "Busyness" 5187.413795 ################
#     2. "Complexity" 962.295917 #
#     3. "Coarseness" 689.073914
#     4.   "Contrast" 530.597275
#     5.   "Strength" 441.737342
#
#
#
# Loss: BINOMIAL_LOG_LIKELIHOOD
# Validation loss value: 0.571505
# Number of trees per iteration: 1
# Node format: NOT_SET
# Number of trees: 48
# Total number of nodes: 2448
#
# Number of nodes by tree:
# Count: 48 Average: 51 StdDev: 9.00925
# Min: 33 Max: 63 Ignored: 0
# ----------------------------------------------
# [ 33, 34) 1   2.08%   2.08% #
# [ 34, 36) 1   2.08%   4.17% #
# [ 36, 37) 0   0.00%   4.17%
# [ 37, 39) 1   2.08%   6.25% #
# [ 39, 40) 3   6.25%  12.50% ####
# [ 40, 42) 3   6.25%  18.75% ####
# [ 42, 43) 0   0.00%  18.75%
# [ 43, 45) 3   6.25%  25.00% ####
# [ 45, 46) 5  10.42%  35.42% #######
# [ 46, 48) 4   8.33%  43.75% ######
# [ 48, 50) 5  10.42%  54.17% #######
# [ 50, 51) 0   0.00%  54.17%
# [ 51, 53) 1   2.08%  56.25% #
# [ 53, 54) 1   2.08%  58.33% #
# [ 54, 56) 0   0.00%  58.33%
# [ 56, 57) 0   0.00%  58.33%
# [ 57, 59) 3   6.25%  64.58% ####
# [ 59, 60) 4   8.33%  72.92% ######
# [ 60, 62) 7  14.58%  87.50% ##########
# [ 62, 63] 6  12.50% 100.00% #########
#
# Depth by leafs:
# Count: 1248 Average: 4.84054 StdDev: 0.501015
# Min: 2 Max: 5 Ignored: 0
# ----------------------------------------------
# [ 2, 3)   16   1.28%   1.28%
# [ 3, 4)   25   2.00%   3.29%
# [ 4, 5)  101   8.09%  11.38% #
# [ 5, 5] 1106  88.62% 100.00% ##########
#
# Number of training obs by leaf:
# Count: 1248 Average: 264.192 StdDev: 723.559
# Min: 5 Max: 6540 Ignored: 0
# ----------------------------------------------
# [    5,  331) 1059  84.86%  84.86% ##########
# [  331,  658)   62   4.97%  89.82% #
# [  658,  985)   31   2.48%  92.31%
# [  985, 1312)   32   2.56%  94.87%
# [ 1312, 1639)   16   1.28%  96.15%
# [ 1639, 1965)    5   0.40%  96.55%
# [ 1965, 2292)    6   0.48%  97.04%
# [ 2292, 2619)    4   0.32%  97.36%
# [ 2619, 2946)    3   0.24%  97.60%
# [ 2946, 3273)    4   0.32%  97.92%
# [ 3273, 3599)    5   0.40%  98.32%
# [ 3599, 3926)    9   0.72%  99.04%
# [ 3926, 4253)    2   0.16%  99.20%
# [ 4253, 4580)    3   0.24%  99.44%
# [ 4580, 4907)    2   0.16%  99.60%
# [ 4907, 5233)    1   0.08%  99.68%
# [ 5233, 5560)    1   0.08%  99.76%
# [ 5560, 5887)    0   0.00%  99.76%
# [ 5887, 6214)    1   0.08%  99.84%
# [ 6214, 6540]    2   0.16% 100.00%
#
# Attribute in nodes:
# 	392 : Busyness [NUMERICAL]
# 	227 : Complexity [NUMERICAL]
# 	219 : Strength [NUMERICAL]
# 	203 : Coarseness [NUMERICAL]
# 	159 : Contrast [NUMERICAL]
#
# Attribute in nodes with depth <= 0:
# 	43 : Busyness [NUMERICAL]
# 	5 : Coarseness [NUMERICAL]
#
# Attribute in nodes with depth <= 1:
# 	78 : Busyness [NUMERICAL]
# 	34 : Coarseness [NUMERICAL]
# 	14 : Complexity [NUMERICAL]
# 	13 : Strength [NUMERICAL]
# 	5 : Contrast [NUMERICAL]
#
# Attribute in nodes with depth <= 2:
# 	139 : Busyness [NUMERICAL]
# 	59 : Complexity [NUMERICAL]
# 	59 : Coarseness [NUMERICAL]
# 	39 : Strength [NUMERICAL]
# 	24 : Contrast [NUMERICAL]
#
# Attribute in nodes with depth <= 3:
# 	239 : Busyness [NUMERICAL]
# 	134 : Complexity [NUMERICAL]
# 	107 : Coarseness [NUMERICAL]
# 	96 : Strength [NUMERICAL]
# 	71 : Contrast [NUMERICAL]
#
# Attribute in nodes with depth <= 5:
# 	392 : Busyness [NUMERICAL]
# 	227 : Complexity [NUMERICAL]
# 	219 : Strength [NUMERICAL]
# 	203 : Coarseness [NUMERICAL]
# 	159 : Contrast [NUMERICAL]
#
# Condition type in nodes:
# 	1200 : HigherCondition
# Condition type in nodes with depth <= 0:
# 	48 : HigherCondition
# Condition type in nodes with depth <= 1:
# 	144 : HigherCondition
# Condition type in nodes with depth <= 2:
# 	320 : HigherCondition
# Condition type in nodes with depth <= 3:
# 	647 : HigherCondition
# Condition type in nodes with depth <= 5:
# 	1200 : HigherCondition
#
# Training logs:
# Number of iteration to final model: 48
# 	Iter:1 train-loss:1.259150 valid-loss:1.267412  train-accuracy:0.887999 valid-accuracy:0.873770
# 	Iter:2 train-loss:1.155006 valid-loss:1.171345  train-accuracy:0.897099 valid-accuracy:0.859038
# 	Iter:3 train-loss:1.066629 valid-loss:1.090864  train-accuracy:0.894118 valid-accuracy:0.879664
# 	Iter:4 train-loss:0.992386 valid-loss:1.022542  train-accuracy:0.895055 valid-accuracy:0.878927
# 	Iter:5 train-loss:0.926459 valid-loss:0.962081  train-accuracy:0.903070 valid-accuracy:0.876717
# 	Iter:6 train-loss:0.866932 valid-loss:0.910363  train-accuracy:0.905565 valid-accuracy:0.873034
# 	Iter:16 train-loss:0.551678 valid-loss:0.659515  train-accuracy:0.918669 valid-accuracy:0.886695
# 	Iter:26 train-loss:0.426315 valid-loss:0.611656  train-accuracy:0.935191 valid-accuracy:0.885958
# 	Iter:36 train-loss:0.361703 valid-loss:0.602222  train-accuracy:0.942769 valid-accuracy:0.886695
# 	Iter:46 train-loss:0.319258 valid-loss:0.578735  train-accuracy:0.947703 valid-accuracy:0.885958
# 	Iter:56 train-loss:0.289835 valid-loss:0.580391  train-accuracy:0.954541 valid-accuracy:0.886695
# 	Iter:66 train-loss:0.264851 valid-loss:0.587384  train-accuracy:0.961026 valid-accuracy:0.878190
# 	Iter:76 train-loss:0.241835 valid-loss:0.593134  train-accuracy:0.968716 valid-accuracy:0.868949

# %%
# Model features
model.make_inspector().features()
# Out:
# ["Busyness" (1; #0),
#  "Coarseness" (1; #1),
#  "Complexity" (1; #2),
#  "Contrast" (1; #3),
#  "Strength" (1; #4)]

# %%
# Feature importance
model.make_inspector().variable_importances()
# Out:
# {'INV_MEAN_MIN_DEPTH': [("Busyness" (1; #0), 0.8100625146850886),
#   ("Coarseness" (1; #1), 0.2596089007261273),
#   ("Complexity" (1; #2), 0.23587171046524041),
#   ("Strength" (1; #4), 0.21674820630480462),
#   ("Contrast" (1; #3), 0.20190468833430086)],
#  'NUM_AS_ROOT': [("Busyness" (1; #0), 43.0), ("Coarseness" (1; #1), 5.0)],
#  'SUM_SCORE': [("Busyness" (1; #0), 5187.413795300618),
#   ("Complexity" (1; #2), 962.2959167705397),
#   ("Coarseness" (1; #1), 689.0739139095316),
#   ("Contrast" (1; #3), 530.5972748041856),
#   ("Strength" (1; #4), 441.7373423728073)],
#  'NUM_NODES': [("Busyness" (1; #0), 392.0),
#   ("Complexity" (1; #2), 227.0),
#   ("Strength" (1; #4), 219.0),
#   ("Coarseness" (1; #1), 203.0),
#   ("Contrast" (1; #3), 159.0)]}

# %%
# Model self evaluation
model.make_inspector().evaluation()
# Out:
# Evaluation(num_examples=None, accuracy=0.8859580159187317, loss=0.5715053081512451, rmse=None, ndcg=None, aucs=None, auuc=None, qini=None)

# %%
logs = model.make_inspector().training_logs()

plt.figure(figsize=(12, 4))
plt.subplot(1, 2, 1)
plt.plot([log.num_trees for log in logs], [log.evaluation.accuracy for log in logs])
plt.xlabel("Number of trees")
plt.ylabel("Accuracy (out-of-bag)")
plt.subplot(1, 2, 2)
plt.plot([log.num_trees for log in logs], [log.evaluation.loss for log in logs])
plt.xlabel("Number of trees")
plt.ylabel("Logloss (out-of-bag)")
plt.show()

# %% [markdown]
# Calculate the score of our hold-out validation dataset

# %%
predictions = model.predict(val_ds)
y_true      = validation_data["label"]

from sklearn.metrics import roc_auc_score
ROC_AUC = roc_auc_score(y_true, predictions)
print("The ROC AUC score is %.5f" % ROC_AUC )
# Out:
# 1/2 [==============>...............] - ETA: 0s
# 2/2 [==============================] - 0s 2ms/step
# The ROC AUC score is 0.98311

# %%
# Compute binary classification metrics with sklearn
import numpy as np
from sklearn.metrics import (
    accuracy_score,
    precision_score,
    recall_score,
    f1_score,
    roc_auc_score,
    average_precision_score,
    confusion_matrix,
    classification_report,
    matthews_corrcoef,
    log_loss,
    brier_score_loss,
)

# Get predictions (probabilities or class labels)
preds = model.predict(test_ds)
# If model outputs probabilities, convert to labels by threshold 0.5
if preds.ndim == 2:
    # For TFDF classification, preds may be class probabilities with shape (N, 2)
    if preds.shape[1] == 2:
        pos_probs = preds[:, 1]
    else:
        # If single-probability column (positive class)
        pos_probs = preds[:, -1]
    y_pred = (pos_probs >= 0.5).astype(int)
else:
    # Already class labels
    y_pred = preds.astype(int)
    pos_probs = None

# Ground truth labels (must be 0/1 integers)
y_true = test_data["label"].astype(int).to_numpy()

# Core metrics
metrics = {}
metrics["accuracy"] = accuracy_score(y_true, y_pred)
metrics["precision"] = precision_score(y_true, y_pred, zero_division=0)
metrics["recall"] = recall_score(y_true, y_pred, zero_division=0)
metrics["f1"] = f1_score(y_true, y_pred, zero_division=0)
metrics["mcc"] = matthews_corrcoef(y_true, y_pred)

# Probabilistic metrics (only if we have probabilities)
if pos_probs is not None:
    metrics["roc_auc"] = roc_auc_score(y_true, pos_probs)
    metrics["pr_auc"] = average_precision_score(y_true, pos_probs)
    metrics["log_loss"] = log_loss(y_true, pos_probs, labels=[0,1])
    metrics["brier_score"] = brier_score_loss(y_true, pos_probs)

# Confusion matrix and detailed report
cm = confusion_matrix(y_true, y_pred, labels=[0,1])
report = classification_report(y_true, y_pred, digits=4)

print("Sklearn binary metrics:")
for k, v in metrics.items():
    print(f"{k}: {v:.4f}")
print("\nConfusion matrix:\n", cm)
print("\nClassification report:\n", report)
# Out:
# 1/3 [=========>....................] - ETA: 0s
# 3/3 [==============================] - 0s 2ms/step
# Sklearn binary metrics:
# accuracy: 0.9426
# precision: 0.6920
# recall: 0.7621
# f1: 0.7254
# mcc: 0.6944
# roc_auc: 0.9549
# pr_auc: 0.7976
# log_loss: 0.1725
# brier_score: 0.0448
#
# Confusion matrix:
#  [[1979   77]
#  [  54  173]]
#
# Classification report:
#                precision    recall  f1-score   support
#
#            0     0.9734    0.9625    0.9680      2056
#            1     0.6920    0.7621    0.7254       227
#
#     accuracy                         0.9426      2283
#    macro avg     0.8327    0.8623    0.8467      2283
# weighted avg     0.9455    0.9426    0.9438      2283
