# %%
# Import packages and modules
import numpy  as np
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow_decision_forests as tfdf

from sklearn.model_selection import train_test_split
# Out:
# 2026-09-11 08:14:33.553952: I tensorflow/core/util/port.cc:113] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2026-09-11 08:14:33.593608: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2026-09-11 08:14:37.858478: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
# Check the version of TensorFlow Decision Forests
print("Found TensorFlow Decision Forests v" + tfdf.__version__)
# Out:
# Found TensorFlow Decision Forests v1.9.1

# %%
datasetPath = "dataset/10p/all/kernel3/"

# %%
# Parameters
datasetPath = "dataset/10p/all/kernel5/"

# %%
# train/validation/test = 70/10/20
train_data = pd.read_csv(f"{datasetPath}dataset.train.csv")
validation_data = pd.read_csv(f"{datasetPath}dataset.validation.csv")
test_data = pd.read_csv(f"{datasetPath}dataset.test.csv")

# %%
from sklearn.utils.class_weight import compute_class_weight

# tinh class weight tren tap train
classes = np.array([0, 1])
weights = compute_class_weight(class_weight="balanced", classes=classes, y=train_data["label"])
class_weight = {0: weights[0], 1: weights[1]}

# gan sample_weight cho tung dong
train_data["sample_weight"] = train_data["label"].map(class_weight)
validation_data["sample_weight"] = validation_data["label"].map(class_weight)
test_data["sample_weight"] = test_data["label"].map(class_weight)

# Convert the dataset into a TensorFlow dataset.
train_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    train_data, label="label", weight="sample_weight"
)         
val_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    validation_data, label="label", weight="sample_weight"
)
test_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    test_data, label="label", weight="sample_weight"
)
# Out:
# 2026-09-11 08:14:49.830277: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:984] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2026-09-11 08:14:49.831793: W tensorflow/core/common_runtime/gpu/gpu_device.cc:2251] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...

# %%
import keras

# %%
# %%time

# Train a Gradient Boosted Trees model.
model = tfdf.keras.GradientBoostedTreesModel()

# Add evaluation metrics
model.compile(
    metrics=["accuracy"]
)
model.fit(x=train_ds)

# # Train a Gradient Boosted Trees model.
# model = tfdf.keras.GradientBoostedTreesModel(num_trees=1500)
# model.fit(train_ds)
# Out:
# Use /tmp/tmpgffeb7wc as temporary training directory
# Reading training dataset...
# [WARNING 26-09-11 08:14:50.1030 UTC gradient_boosted_trees.cc:1840] "goss_alpha" set but "sampling_method" not equal to "GOSS".
# [WARNING 26-09-11 08:14:50.1031 UTC gradient_boosted_trees.cc:1851] "goss_beta" set but "sampling_method" not equal to "GOSS".
# [WARNING 26-09-11 08:14:50.1031 UTC gradient_boosted_trees.cc:1865] "selective_gradient_boosting_ratio" set but "sampling_method" not equal to "SELGB".
# Training dataset read in 0:00:03.306031. Found 7617 examples.
# Training model...
# Model trained in 0:00:04.078046
# Compiling model...
# [INFO 26-09-11 08:14:57.5057 UTC kernel.cc:1233] Loading model from path /tmp/tmpgffeb7wc/model/ with prefix 6b24c5e6ef6a4fda
# [INFO 26-09-11 08:14:57.5088 UTC quick_scorer_extended.cc:911] The binary was compiled without AVX2 support, but your CPU supports it. Enable it for faster model inference.
# [INFO 26-09-11 08:14:57.5090 UTC abstract_model.cc:1362] Engine "GradientBoostedTreesQuickScorerExtended" built
# [INFO 26-09-11 08:14:57.5091 UTC kernel.cc:1061] Use fast generic engine
# Model compiled.
# CPU times: user 23.6 s, sys: 2.48 s, total: 26.1 s
# Wall time: 11 s

# %%
# Evaluate the model
evaluate = model.evaluate(val_ds, return_dict=True)
print()

for name, value in evaluate.items():
    print(f"{name}: {value:.4f}")
# Out:
# WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 1/2 [==============>...............] - ETA: 3s - loss: 0.0000e+00 - accuracy: 0.9900
# 2/2 [==============================] - 3s 9ms/step - loss: 0.0000e+00 - accuracy: 0.9888
# loss: 0.0000
# accuracy: 0.9888

# %%
# Model Summary
model.summary()
# Out:
# Model: "gradient_boosted_trees_model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
# =================================================================
# Total params: 1 (1.00 Byte)
# Trainable params: 0 (0.00 Byte)
# Non-trainable params: 1 (1.00 Byte)
# _________________________________________________________________
# Type: "GRADIENT_BOOSTED_TREES"
# Task: CLASSIFICATION
# Label: "__LABEL"
#
# Input Features (93):
# 	10Percentile
# 	90Percentile
# 	Autocorrelation
# 	Busyness
# 	ClusterProminence
# 	ClusterShade
# 	ClusterTendency
# 	Coarseness
# 	Complexity
# 	Contrast
# 	Contrast.1
# 	Correlation
# 	DependenceEntropy
# 	DependenceNonUniformity
# 	DependenceNonUniformityNormalized
# 	DependenceVariance
# 	DifferenceAverage
# 	DifferenceEntropy
# 	DifferenceVariance
# 	Energy
# 	Entropy
# 	GrayLevelNonUniformity
# 	GrayLevelNonUniformity.1
# 	GrayLevelNonUniformity.2
# 	GrayLevelNonUniformityNormalized
# 	GrayLevelNonUniformityNormalized.1
# 	GrayLevelVariance
# 	GrayLevelVariance.1
# 	GrayLevelVariance.2
# 	HighGrayLevelEmphasis
# 	HighGrayLevelRunEmphasis
# 	HighGrayLevelZoneEmphasis
# 	Id
# 	Idm
# 	Idmn
# 	Idn
# 	Imc1
# 	Imc2
# 	InterquartileRange
# 	InverseVariance
# 	JointAverage
# 	JointEnergy
# 	JointEntropy
# 	Kurtosis
# 	LargeAreaEmphasis
# 	LargeAreaHighGrayLevelEmphasis
# 	LargeAreaLowGrayLevelEmphasis
# 	LargeDependenceEmphasis
# 	LargeDependenceHighGrayLevelEmphasis
# 	LargeDependenceLowGrayLevelEmphasis
# 	LongRunEmphasis
# 	LongRunHighGrayLevelEmphasis
# 	LongRunLowGrayLevelEmphasis
# 	LowGrayLevelEmphasis
# 	LowGrayLevelRunEmphasis
# 	LowGrayLevelZoneEmphasis
# 	MCC
# 	Maximum
# 	MaximumProbability
# 	Mean
# 	MeanAbsoluteDeviation
# 	Median
# 	Minimum
# 	Range
# 	RobustMeanAbsoluteDeviation
# 	RootMeanSquared
# 	RunEntropy
# 	RunLengthNonUniformity
# 	RunLengthNonUniformityNormalized
# 	RunPercentage
# 	RunVariance
# 	ShortRunEmphasis
# 	ShortRunHighGrayLevelEmphasis
# 	ShortRunLowGrayLevelEmphasis
# 	SizeZoneNonUniformity
# 	SizeZoneNonUniformityNormalized
# 	Skewness
# 	SmallAreaEmphasis
# 	SmallAreaHighGrayLevelEmphasis
# 	SmallAreaLowGrayLevelEmphasis
# 	SmallDependenceEmphasis
# 	SmallDependenceHighGrayLevelEmphasis
# 	SmallDependenceLowGrayLevelEmphasis
# 	Strength
# 	SumAverage
# 	SumEntropy
# 	SumSquares
# 	TotalEnergy
# 	Uniformity
# 	Variance
# 	ZoneEntropy
# 	ZonePercentage
# 	ZoneVariance
#
# Trained with weights
#
# Variable Importance: INV_MEAN_MIN_DEPTH:
#     1.         "LongRunHighGrayLevelEmphasis"  0.278548 ################
#     2. "LargeDependenceHighGrayLevelEmphasis"  0.265031 #############
#     3.                                  "Idn"  0.219867 #######
#     4.                             "Busyness"  0.202331 ####
#     5.                           "Coarseness"  0.201602 ####
#     6.       "LargeAreaHighGrayLevelEmphasis"  0.186782 ##
#     7.                              "Maximum"  0.186161 ##
#     8.                               "Median"  0.185670 #
#     9.                    "DependenceEntropy"  0.185445 #
#    10.                             "Skewness"  0.182680 #
#    11.                         "ClusterShade"  0.181541 #
#    12.       "SmallAreaHighGrayLevelEmphasis"  0.181430 #
#    13.                                 "Idmn"  0.179625 #
#    14.             "GrayLevelNonUniformity.2"  0.177994
#    15.         "ShortRunLowGrayLevelEmphasis"  0.177964
#    16.             "LowGrayLevelZoneEmphasis"  0.177685
#    17.                         "90Percentile"  0.177060
#    18.                                  "MCC"  0.176435
#    19.                                "Range"  0.176305
#    20.              "DependenceNonUniformity"  0.175834
#    21.                        "RunPercentage"  0.175497
#    22.                           "Contrast.1"  0.175429
#    23.                                 "Imc1"  0.174964
#    24.  "LargeDependenceLowGrayLevelEmphasis"  0.174890
#    25.            "HighGrayLevelZoneEmphasis"  0.174382
#    26.  "SmallDependenceLowGrayLevelEmphasis"  0.174128
#    27.                             "Strength"  0.174045
#    28.                   "DifferenceVariance"  0.173879
#    29.                             "Contrast"  0.173821
#    30.                              "Entropy"  0.173812
#    31.        "LargeAreaLowGrayLevelEmphasis"  0.173772
#    32.                      "Autocorrelation"  0.173694
#    33.                         "JointAverage"  0.173621
#    34.                              "Minimum"  0.173558
#    35.               "GrayLevelNonUniformity"  0.173545
#    36.                 "LowGrayLevelEmphasis"  0.173533
#    37.                             "Kurtosis"  0.173524
#    38.                      "InverseVariance"  0.173511
#    39.                      "RootMeanSquared"  0.173506
#    40.        "SmallAreaLowGrayLevelEmphasis"  0.173461
#    41.          "LongRunLowGrayLevelEmphasis"  0.173445
#    42.                          "ZoneEntropy"  0.173371
#    43.                          "JointEnergy"  0.173364
#    44.                          "RunVariance"  0.173301
#    45.                         "10Percentile"  0.173290
#    46.                    "DifferenceAverage"  0.173270
#    47.                          "Correlation"  0.173238
#    48.                "MeanAbsoluteDeviation"  0.173212
#    49.                           "SumEntropy"  0.173130
#    50.                   "MaximumProbability"  0.173127
#    51.                   "DependenceVariance"  0.173115
#    52.                           "Complexity"  0.173113
#    53.                    "ClusterProminence"  0.173097
#    54.                           "Uniformity"  0.173079
#    55.                    "SmallAreaEmphasis"  0.173047
#    56.                       "ZonePercentage"  0.173030
#    57.     "RunLengthNonUniformityNormalized"  0.173023
#    58.             "GrayLevelNonUniformity.1"  0.173014
#    59.                "SizeZoneNonUniformity"  0.173004
#    60.              "LargeDependenceEmphasis"  0.172965
#    61.                                  "Idm"  0.172955
#    62.    "DependenceNonUniformityNormalized"  0.172917
#    63. "SmallDependenceHighGrayLevelEmphasis"  0.172911
#    64.                         "ZoneVariance"  0.172905
#    65.                  "GrayLevelVariance.2"  0.172890
#    66.                                 "Mean"  0.172851
#    67.      "SizeZoneNonUniformityNormalized"  0.172821
#    68.                  "GrayLevelVariance.1"  0.172797
#    69.              "SmallDependenceEmphasis"  0.172758
#    70.                   "InterquartileRange"  0.172758
#    71.                                 "Imc2"  0.172727
#    72.     "GrayLevelNonUniformityNormalized"  0.172680
#    73.   "GrayLevelNonUniformityNormalized.1"  0.172651
#    74.                    "DifferenceEntropy"  0.172639
#    75.                           "SumSquares"  0.172629
#    76.                           "RunEntropy"  0.172620
#    77.          "RobustMeanAbsoluteDeviation"  0.172610
#    78.                      "ClusterTendency"  0.172605
#    79.                      "LongRunEmphasis"  0.172578
#    80.                    "LargeAreaEmphasis"  0.172576
#    81.             "HighGrayLevelRunEmphasis"  0.172548
#    82.               "RunLengthNonUniformity"  0.172542
#    83.                          "TotalEnergy"  0.172533
#    84.                     "ShortRunEmphasis"  0.172530
#    85.                                   "Id"  0.172525
#    86.                         "JointEntropy"  0.172521
#    87.                               "Energy"  0.172520
#    88.        "ShortRunHighGrayLevelEmphasis"  0.172506
#    89.              "LowGrayLevelRunEmphasis"  0.172486
#    90.                "HighGrayLevelEmphasis"  0.172481
#    91.                           "SumAverage"  0.172474
#    92.                             "Variance"  0.172443
#
# Variable Importance: NUM_AS_ROOT:
#     1.         "LongRunHighGrayLevelEmphasis" 27.000000 ################
#     2. "LargeDependenceHighGrayLevelEmphasis" 14.000000 ########
#     3.                             "Busyness"  7.000000 ###
#     4.                           "Coarseness"  5.000000 ##
#     5.                    "DependenceEntropy"  3.000000 #
#     6.                              "Maximum"  3.000000 #
#     7.                               "Median"  2.000000
#     8.                                  "MCC"  1.000000
#
# Variable Importance: NUM_NODES:
#     1.                                  "Idn" 147.000000 ################
#     2. "LargeDependenceHighGrayLevelEmphasis" 126.000000 #############
#     3.         "LongRunHighGrayLevelEmphasis" 100.000000 ##########
#     4.                           "Coarseness" 76.000000 ########
#     5.                             "Busyness" 65.000000 #######
#     6.                             "Skewness" 58.000000 ######
#     7.                                 "Idmn" 54.000000 #####
#     8.       "LargeAreaHighGrayLevelEmphasis" 52.000000 #####
#     9.                               "Median" 47.000000 #####
#    10.                         "ClusterShade" 43.000000 ####
#    11.                              "Maximum" 42.000000 ####
#    12.                    "DependenceEntropy" 36.000000 ###
#    13.                         "90Percentile" 34.000000 ###
#    14.             "GrayLevelNonUniformity.2" 34.000000 ###
#    15.       "SmallAreaHighGrayLevelEmphasis" 27.000000 ##
#    16.                                 "Imc1" 20.000000 ##
#    17.                                "Range" 20.000000 ##
#    18.         "ShortRunLowGrayLevelEmphasis" 20.000000 ##
#    19.                           "Contrast.1" 19.000000 #
#    20.  "LargeDependenceLowGrayLevelEmphasis" 18.000000 #
#    21.  "SmallDependenceLowGrayLevelEmphasis" 18.000000 #
#    22.             "LowGrayLevelZoneEmphasis" 17.000000 #
#    23.                   "DifferenceVariance" 16.000000 #
#    24.        "LargeAreaLowGrayLevelEmphasis" 16.000000 #
#    25.                                  "MCC" 15.000000 #
#    26.                              "Minimum" 15.000000 #
#    27.                          "ZoneEntropy" 15.000000 #
#    28.            "HighGrayLevelZoneEmphasis" 13.000000 #
#    29.                             "Kurtosis" 13.000000 #
#    30.                        "RunPercentage" 13.000000 #
#    31.                      "Autocorrelation" 12.000000 #
#    32.                              "Entropy" 12.000000 #
#    33.                          "JointEnergy" 12.000000 #
#    34.          "LongRunLowGrayLevelEmphasis" 12.000000 #
#    35.        "SmallAreaLowGrayLevelEmphasis" 12.000000 #
#    36.                         "10Percentile" 10.000000
#    37.                          "Correlation" 10.000000
#    38.                   "DependenceVariance" 10.000000
#    39.               "GrayLevelNonUniformity" 10.000000
#    40.                           "SumEntropy" 10.000000
#    41.                    "DifferenceAverage"  9.000000
#    42.                      "InverseVariance"  9.000000
#    43.                                 "Mean"  9.000000
#    44.                           "Complexity"  8.000000
#    45.              "DependenceNonUniformity"  8.000000
#    46.                "SizeZoneNonUniformity"  8.000000
#    47.                    "ClusterProminence"  7.000000
#    48.                             "Contrast"  7.000000
#    49.             "GrayLevelNonUniformity.1"  7.000000
#    50.                   "MaximumProbability"  7.000000
#    51.                "MeanAbsoluteDeviation"  7.000000
#    52.                          "RunVariance"  7.000000
#    53. "SmallDependenceHighGrayLevelEmphasis"  7.000000
#    54.                             "Strength"  7.000000
#    55.                       "ZonePercentage"  7.000000
#    56.                  "GrayLevelVariance.2"  6.000000
#    57.                         "JointAverage"  6.000000
#    58.      "SizeZoneNonUniformityNormalized"  6.000000
#    59.                    "SmallAreaEmphasis"  6.000000
#    60.    "DependenceNonUniformityNormalized"  5.000000
#    61.                                  "Idm"  5.000000
#    62.                                 "Imc2"  5.000000
#    63.                      "RootMeanSquared"  5.000000
#    64.     "RunLengthNonUniformityNormalized"  5.000000
#    65.     "GrayLevelNonUniformityNormalized"  4.000000
#    66.   "GrayLevelNonUniformityNormalized.1"  4.000000
#    67.             "HighGrayLevelRunEmphasis"  4.000000
#    68.                   "InterquartileRange"  4.000000
#    69.                      "LongRunEmphasis"  4.000000
#    70.                 "LowGrayLevelEmphasis"  4.000000
#    71.               "RunLengthNonUniformity"  4.000000
#    72.              "SmallDependenceEmphasis"  4.000000
#    73.                           "Uniformity"  4.000000
#    74.                      "ClusterTendency"  3.000000
#    75.                    "DifferenceEntropy"  3.000000
#    76.                               "Energy"  3.000000
#    77.                  "GrayLevelVariance.1"  3.000000
#    78.                         "JointEntropy"  3.000000
#    79.              "LargeDependenceEmphasis"  3.000000
#    80.          "RobustMeanAbsoluteDeviation"  3.000000
#    81.        "ShortRunHighGrayLevelEmphasis"  3.000000
#    82.                         "ZoneVariance"  3.000000
#    83.                "HighGrayLevelEmphasis"  2.000000
#    84.                    "LargeAreaEmphasis"  2.000000
#    85.              "LowGrayLevelRunEmphasis"  2.000000
#    86.                           "RunEntropy"  2.000000
#    87.                     "ShortRunEmphasis"  2.000000
#    88.                           "SumAverage"  2.000000
#    89.                           "SumSquares"  2.000000
#    90.                          "TotalEnergy"  2.000000
#    91.                                   "Id"  1.000000
#    92.                             "Variance"  1.000000
#
# Variable Importance: SUM_SCORE:
#     1.         "LongRunHighGrayLevelEmphasis" 4710.757660 ################
#     2. "LargeDependenceHighGrayLevelEmphasis" 905.026312 ###
#     3.                                  "Idn" 674.394693 ##
#     4.                             "Busyness" 476.077090 #
#     5.                           "Coarseness" 245.652654
#     6.             "GrayLevelNonUniformity.2" 220.857735
#     7.                              "Maximum" 130.409418
#     8.                                 "Idmn" 125.541283
#     9.                             "Skewness" 115.738338
#    10.       "LargeAreaHighGrayLevelEmphasis" 101.958007
#    11.                               "Median" 100.076185
#    12.                             "Kurtosis" 84.373634
#    13.                    "DependenceEntropy" 75.796735
#    14.                                 "Imc1" 59.419129
#    15.          "LongRunLowGrayLevelEmphasis" 57.895428
#    16.                           "Contrast.1" 51.392752
#    17.                                "Range" 44.661917
#    18.                         "90Percentile" 44.397959
#    19.       "SmallAreaHighGrayLevelEmphasis" 40.138958
#    20.                        "RunPercentage" 31.225717
#    21.             "LowGrayLevelZoneEmphasis" 30.940543
#    22.  "SmallDependenceLowGrayLevelEmphasis" 29.648035
#    23.         "ShortRunLowGrayLevelEmphasis" 27.538851
#    24.                                 "Mean" 27.290524
#    25.                       "ZonePercentage" 26.488868
#    26.                         "ClusterShade" 25.515134
#    27.                      "Autocorrelation" 25.454505
#    28.    "DependenceNonUniformityNormalized" 23.420268
#    29.  "LargeDependenceLowGrayLevelEmphasis" 23.389614
#    30.                   "DifferenceVariance" 23.040545
#    31.                              "Minimum" 22.437981
#    32.     "RunLengthNonUniformityNormalized" 21.323118
#    33.            "HighGrayLevelZoneEmphasis" 21.311980
#    34.                "MeanAbsoluteDeviation" 18.039311
#    35.              "DependenceNonUniformity" 17.287327
#    36.               "GrayLevelNonUniformity" 16.940224
#    37.                          "JointEnergy" 16.348466
#    38.                "SizeZoneNonUniformity" 16.226154
#    39.                                  "MCC" 16.033420
#    40.        "LargeAreaLowGrayLevelEmphasis" 15.301299
#    41.                    "ClusterProminence" 14.590311
#    42.                         "10Percentile" 14.149213
#    43.                          "ZoneEntropy" 14.072625
#    44.                           "Uniformity" 12.272569
#    45.                         "ZoneVariance" 11.566778
#    46.                    "DifferenceAverage" 10.694764
#    47.                    "LargeAreaEmphasis" 10.643495
#    48.                              "Entropy"  9.475449
#    49.     "GrayLevelNonUniformityNormalized"  8.993141
#    50.                                 "Imc2"  8.792058
#    51.                             "Strength"  8.121527
#    52.        "SmallAreaLowGrayLevelEmphasis"  8.114353
#    53.      "SizeZoneNonUniformityNormalized"  7.864352
#    54. "SmallDependenceHighGrayLevelEmphasis"  7.483508
#    55.                          "Correlation"  7.480843
#    56.                  "GrayLevelVariance.2"  7.236701
#    57.                           "RunEntropy"  7.199966
#    58.                      "LongRunEmphasis"  6.800190
#    59.                    "SmallAreaEmphasis"  6.496843
#    60.                      "ClusterTendency"  6.440459
#    61.                           "SumEntropy"  6.035543
#    62.                             "Contrast"  5.657302
#    63.                               "Energy"  5.516677
#    64.                          "RunVariance"  5.271218
#    65.                                  "Idm"  4.981285
#    66.                           "Complexity"  4.313081
#    67.                      "RootMeanSquared"  3.471595
#    68.                   "InterquartileRange"  2.853885
#    69.                    "DifferenceEntropy"  2.540349
#    70.   "GrayLevelNonUniformityNormalized.1"  2.520284
#    71.             "GrayLevelNonUniformity.1"  2.330601
#    72.                           "SumAverage"  2.031910
#    73.                   "DependenceVariance"  1.784214
#    74.                  "GrayLevelVariance.1"  1.745122
#    75.                      "InverseVariance"  1.601193
#    76.                         "JointAverage"  1.490728
#    77.              "LowGrayLevelRunEmphasis"  1.481128
#    78.                   "MaximumProbability"  1.465496
#    79.                "HighGrayLevelEmphasis"  1.454027
#    80.                           "SumSquares"  1.192695
#    81.             "HighGrayLevelRunEmphasis"  0.794103
#    82.                          "TotalEnergy"  0.773636
#    83.        "ShortRunHighGrayLevelEmphasis"  0.737014
#    84.               "RunLengthNonUniformity"  0.665530
#    85.              "LargeDependenceEmphasis"  0.529058
#    86.              "SmallDependenceEmphasis"  0.514039
#    87.          "RobustMeanAbsoluteDeviation"  0.473121
#    88.                 "LowGrayLevelEmphasis"  0.249113
#    89.                     "ShortRunEmphasis"  0.218166
#    90.                                   "Id"  0.129051
#    91.                         "JointEntropy"  0.103075
#    92.                             "Variance"  0.059887
#
#
#
# Loss: BINOMIAL_LOG_LIKELIHOOD
# Validation loss value: 0.324981
# Number of trees per iteration: 1
# Node format: NOT_SET
# Number of trees: 62
# Total number of nodes: 3148
#
# Number of nodes by tree:
# Count: 62 Average: 50.7742 StdDev: 8.30161
# Min: 25 Max: 61 Ignored: 0
# ----------------------------------------------
# [ 25, 26)  1   1.61%   1.61% #
# [ 26, 28)  1   1.61%   3.23% #
# [ 28, 30)  0   0.00%   3.23%
# [ 30, 32)  1   1.61%   4.84% #
# [ 32, 34)  0   0.00%   4.84%
# [ 34, 36)  1   1.61%   6.45% #
# [ 36, 37)  0   0.00%   6.45%
# [ 37, 39)  0   0.00%   6.45%
# [ 39, 41)  1   1.61%   8.06% #
# [ 41, 43)  5   8.06%  16.13% ####
# [ 43, 45)  3   4.84%  20.97% ###
# [ 45, 47)  4   6.45%  27.42% ###
# [ 47, 49)  3   4.84%  32.26% ###
# [ 49, 50)  1   1.61%  33.87% #
# [ 50, 52)  7  11.29%  45.16% ######
# [ 52, 54)  4   6.45%  51.61% ###
# [ 54, 56) 12  19.35%  70.97% ##########
# [ 56, 58)  6   9.68%  80.65% #####
# [ 58, 60)  8  12.90%  93.55% #######
# [ 60, 61]  4   6.45% 100.00% ###
#
# Depth by leafs:
# Count: 1605 Average: 4.8243 StdDev: 0.497002
# Min: 2 Max: 5 Ignored: 0
# ----------------------------------------------
# [ 2, 3)   15   0.93%   0.93%
# [ 3, 4)   37   2.31%   3.24%
# [ 4, 5)  163  10.16%  13.40% #
# [ 5, 5] 1390  86.60% 100.00% ##########
#
# Number of training obs by leaf:
# Count: 1605 Average: 265.345 StdDev: 713.781
# Min: 5 Max: 6553 Ignored: 0
# ----------------------------------------------
# [    5,  332) 1370  85.36%  85.36% ##########
# [  332,  659)   80   4.98%  90.34% #
# [  659,  987)   29   1.81%  92.15%
# [  987, 1314)   30   1.87%  94.02%
# [ 1314, 1642)   10   0.62%  94.64%
# [ 1642, 1969)    8   0.50%  95.14%
# [ 1969, 2297)   16   1.00%  96.14%
# [ 2297, 2624)   15   0.93%  97.07%
# [ 2624, 2952)    7   0.44%  97.51%
# [ 2952, 3279)   18   1.12%  98.63%
# [ 3279, 3606)   10   0.62%  99.25%
# [ 3606, 3934)    2   0.12%  99.38%
# [ 3934, 4261)    4   0.25%  99.63%
# [ 4261, 4589)    1   0.06%  99.69%
# [ 4589, 4916)    1   0.06%  99.75%
# [ 4916, 5244)    0   0.00%  99.75%
# [ 5244, 5571)    1   0.06%  99.81%
# [ 5571, 5899)    0   0.00%  99.81%
# [ 5899, 6226)    1   0.06%  99.88%
# [ 6226, 6553]    2   0.12% 100.00%
#
# Attribute in nodes:
# 	147 : Idn [NUMERICAL]
# 	126 : LargeDependenceHighGrayLevelEmphasis [NUMERICAL]
# 	100 : LongRunHighGrayLevelEmphasis [NUMERICAL]
# 	76 : Coarseness [NUMERICAL]
# 	65 : Busyness [NUMERICAL]
# 	58 : Skewness [NUMERICAL]
# 	54 : Idmn [NUMERICAL]
# 	52 : LargeAreaHighGrayLevelEmphasis [NUMERICAL]
# 	47 : Median [NUMERICAL]
# 	43 : ClusterShade [NUMERICAL]
# 	42 : Maximum [NUMERICAL]
# 	36 : DependenceEntropy [NUMERICAL]
# 	34 : GrayLevelNonUniformity.2 [NUMERICAL]
# 	34 : 90Percentile [NUMERICAL]
# 	27 : SmallAreaHighGrayLevelEmphasis [NUMERICAL]
# 	20 : ShortRunLowGrayLevelEmphasis [NUMERICAL]
# 	20 : Range [NUMERICAL]
# 	20 : Imc1 [NUMERICAL]
# 	19 : Contrast.1 [NUMERICAL]
# 	18 : SmallDependenceLowGrayLevelEmphasis [NUMERICAL]
# 	18 : LargeDependenceLowGrayLevelEmphasis [NUMERICAL]
# 	17 : LowGrayLevelZoneEmphasis [NUMERICAL]
# 	16 : LargeAreaLowGrayLevelEmphasis [NUMERICAL]
# 	16 : DifferenceVariance [NUMERICAL]
# 	15 : ZoneEntropy [NUMERICAL]
# 	15 : Minimum [NUMERICAL]
# 	15 : MCC [NUMERICAL]
# 	13 : RunPercentage [NUMERICAL]
# 	13 : Kurtosis [NUMERICAL]
# 	13 : HighGrayLevelZoneEmphasis [NUMERICAL]
# 	12 : SmallAreaLowGrayLevelEmphasis [NUMERICAL]
# 	12 : LongRunLowGrayLevelEmphasis [NUMERICAL]
# 	12 : JointEnergy [NUMERICAL]
# 	12 : Entropy [NUMERICAL]
# 	12 : Autocorrelation [NUMERICAL]
# 	10 : SumEntropy [NUMERICAL]
# 	10 : GrayLevelNonUniformity [NUMERICAL]
# 	10 : DependenceVariance [NUMERICAL]
# 	10 : Correlation [NUMERICAL]
# 	10 : 10Percentile [NUMERICAL]
# 	9 : Mean [NUMERICAL]
# 	9 : InverseVariance [NUMERICAL]
# 	9 : DifferenceAverage [NUMERICAL]
# 	8 : SizeZoneNonUniformity [NUMERICAL]
# 	8 : DependenceNonUniformity [NUMERICAL]
# 	8 : Complexity [NUMERICAL]
# 	7 : ZonePercentage [NUMERICAL]
# 	7 : Strength [NUMERICAL]
# 	7 : SmallDependenceHighGrayLevelEmphasis [NUMERICAL]
# 	7 : RunVariance [NUMERICAL]
# 	7 : MeanAbsoluteDeviation [NUMERICAL]
# 	7 : MaximumProbability [NUMERICAL]
# 	7 : GrayLevelNonUniformity.1 [NUMERICAL]
# 	7 : Contrast [NUMERICAL]
# 	7 : ClusterProminence [NUMERICAL]
# 	6 : SmallAreaEmphasis [NUMERICAL]
# 	6 : SizeZoneNonUniformityNormalized [NUMERICAL]
# 	6 : JointAverage [NUMERICAL]
# 	6 : GrayLevelVariance.2 [NUMERICAL]
# 	5 : RunLengthNonUniformityNormalized [NUMERICAL]
# 	5 : RootMeanSquared [NUMERICAL]
# 	5 : Imc2 [NUMERICAL]
# 	5 : Idm [NUMERICAL]
# 	5 : DependenceNonUniformityNormalized [NUMERICAL]
# 	4 : Uniformity [NUMERICAL]
# 	4 : SmallDependenceEmphasis [NUMERICAL]
# 	4 : RunLengthNonUniformity [NUMERICAL]
# 	4 : LowGrayLevelEmphasis [NUMERICAL]
# 	4 : LongRunEmphasis [NUMERICAL]
# 	4 : InterquartileRange [NUMERICAL]
# 	4 : HighGrayLevelRunEmphasis [NUMERICAL]
# 	4 : GrayLevelNonUniformityNormalized.1 [NUMERICAL]
# 	4 : GrayLevelNonUniformityNormalized [NUMERICAL]
# 	3 : ZoneVariance [NUMERICAL]
# 	3 : ShortRunHighGrayLevelEmphasis [NUMERICAL]
# 	3 : RobustMeanAbsoluteDeviation [NUMERICAL]
# 	3 : LargeDependenceEmphasis [NUMERICAL]
# 	3 : JointEntropy [NUMERICAL]
# 	3 : GrayLevelVariance.1 [NUMERICAL]
# 	3 : Energy [NUMERICAL]
# 	3 : DifferenceEntropy [NUMERICAL]
# 	3 : ClusterTendency [NUMERICAL]
# 	2 : TotalEnergy [NUMERICAL]
# 	2 : SumSquares [NUMERICAL]
# 	2 : SumAverage [NUMERICAL]
# 	2 : ShortRunEmphasis [NUMERICAL]
# 	2 : RunEntropy [NUMERICAL]
# 	2 : LowGrayLevelRunEmphasis [NUMERICAL]
# 	2 : LargeAreaEmphasis [NUMERICAL]
# 	2 : HighGrayLevelEmphasis [NUMERICAL]
# 	1 : Variance [NUMERICAL]
# 	1 : Id [NUMERICAL]
#
# Attribute in nodes with depth <= 0:
# 	27 : LongRunHighGrayLevelEmphasis [NUMERICAL]
# 	14 : LargeDependenceHighGrayLevelEmphasis [NUMERICAL]
# 	7 : Busyness [NUMERICAL]
# 	5 : Coarseness [NUMERICAL]
# 	3 : Maximum [NUMERICAL]
# 	3 : DependenceEntropy [NUMERICAL]
# 	2 : Median [NUMERICAL]
# 	1 : MCC [NUMERICAL]
#
# Attribute in nodes with depth <= 1:
# 	47 : LongRunHighGrayLevelEmphasis [NUMERICAL]
# 	40 : LargeDependenceHighGrayLevelEmphasis [NUMERICAL]
# 	20 : Idn [NUMERICAL]
# 	10 : Coarseness [NUMERICAL]
# 	9 : Busyness [NUMERICAL]
# 	7 : ClusterShade [NUMERICAL]
# 	6 : SmallAreaHighGrayLevelEmphasis [NUMERICAL]
# 	6 : Maximum [NUMERICAL]
# 	6 : LargeAreaHighGrayLevelEmphasis [NUMERICAL]
# 	5 : Skewness [NUMERICAL]
# 	4 : Median [NUMERICAL]
# 	4 : LowGrayLevelZoneEmphasis [NUMERICAL]
# 	4 : DependenceEntropy [NUMERICAL]
# 	3 : ShortRunLowGrayLevelEmphasis [NUMERICAL]
# 	3 : Range [NUMERICAL]
# 	2 : InverseVariance [NUMERICAL]
# 	2 : Idmn [NUMERICAL]
# 	2 : DependenceNonUniformity [NUMERICAL]
# 	2 : Contrast.1 [NUMERICAL]
# 	1 : Strength [NUMERICAL]
# 	1 : RootMeanSquared [NUMERICAL]
# 	1 : MCC [NUMERICAL]
# 	1 : LargeDependenceLowGrayLevelEmphasis [NUMERICAL]
#
# Attribute in nodes with depth <= 2:
# 	54 : Idn [NUMERICAL]
# 	52 : LongRunHighGrayLevelEmphasis [NUMERICAL]
# 	51 : LargeDependenceHighGrayLevelEmphasis [NUMERICAL]
# 	24 : Coarseness [NUMERICAL]
# 	23 : Busyness [NUMERICAL]
# 	17 : LargeAreaHighGrayLevelEmphasis [NUMERICAL]
# 	14 : Skewness [NUMERICAL]
# 	14 : Median [NUMERICAL]
# 	12 : DependenceEntropy [NUMERICAL]
# 	11 : Idmn [NUMERICAL]
# 	11 : GrayLevelNonUniformity.2 [NUMERICAL]
# 	10 : RunPercentage [NUMERICAL]
# 	9 : SmallAreaHighGrayLevelEmphasis [NUMERICAL]
# 	9 : ClusterShade [NUMERICAL]
# 	8 : LowGrayLevelZoneEmphasis [NUMERICAL]
# 	7 : Maximum [NUMERICAL]
# 	7 : MCC [NUMERICAL]
# 	6 : ShortRunLowGrayLevelEmphasis [NUMERICAL]
# 	5 : Range [NUMERICAL]
# 	5 : Imc1 [NUMERICAL]
# 	5 : DependenceNonUniformity [NUMERICAL]
# 	4 : HighGrayLevelZoneEmphasis [NUMERICAL]
# 	4 : 90Percentile [NUMERICAL]
# 	3 : Strength [NUMERICAL]
# 	3 : GrayLevelNonUniformity [NUMERICAL]
# 	3 : Entropy [NUMERICAL]
# 	3 : Contrast.1 [NUMERICAL]
# 	3 : Contrast [NUMERICAL]
# 	3 : Autocorrelation [NUMERICAL]
# 	2 : Uniformity [NUMERICAL]
# 	2 : SmallDependenceLowGrayLevelEmphasis [NUMERICAL]
# 	2 : MeanAbsoluteDeviation [NUMERICAL]
# 	2 : LowGrayLevelEmphasis [NUMERICAL]
# 	2 : LargeDependenceLowGrayLevelEmphasis [NUMERICAL]
# 	2 : LargeAreaLowGrayLevelEmphasis [NUMERICAL]
# 	2 : JointAverage [NUMERICAL]
# 	2 : InverseVariance [NUMERICAL]
# 	2 : DifferenceAverage [NUMERICAL]
# 	1 : ZoneVariance [NUMERICAL]
# 	1 : ZoneEntropy [NUMERICAL]
# 	1 : SumEntropy [NUMERICAL]
# 	1 : SmallDependenceEmphasis [NUMERICAL]
# 	1 : SmallAreaLowGrayLevelEmphasis [NUMERICAL]
# 	1 : SizeZoneNonUniformity [NUMERICAL]
# 	1 : RunVariance [NUMERICAL]
# 	1 : RunLengthNonUniformityNormalized [NUMERICAL]
# 	1 : RootMeanSquared [NUMERICAL]
# 	1 : Minimum [NUMERICAL]
# 	1 : MaximumProbability [NUMERICAL]
# 	1 : LongRunLowGrayLevelEmphasis [NUMERICAL]
# 	1 : LargeDependenceEmphasis [NUMERICAL]
# 	1 : JointEnergy [NUMERICAL]
# 	1 : InterquartileRange [NUMERICAL]
# 	1 : Idm [NUMERICAL]
# 	1 : GrayLevelVariance.1 [NUMERICAL]
# 	1 : DifferenceVariance [NUMERICAL]
# 	1 : Correlation [NUMERICAL]
# 	1 : Complexity [NUMERICAL]
# 	1 : ClusterProminence [NUMERICAL]
#
# Attribute in nodes with depth <= 3:
# 	93 : Idn [NUMERICAL]
# 	77 : LargeDependenceHighGrayLevelEmphasis [NUMERICAL]
# 	67 : LongRunHighGrayLevelEmphasis [NUMERICAL]
# 	45 : Coarseness [NUMERICAL]
# 	37 : Skewness [NUMERICAL]
# 	36 : Busyness [NUMERICAL]
# 	35 : LargeAreaHighGrayLevelEmphasis [NUMERICAL]
# 	30 : ClusterShade [NUMERICAL]
# 	29 : Median [NUMERICAL]
# 	25 : Idmn [NUMERICAL]
# 	23 : Maximum [NUMERICAL]
# 	22 : DependenceEntropy [NUMERICAL]
# 	20 : GrayLevelNonUniformity.2 [NUMERICAL]
# 	17 : 90Percentile [NUMERICAL]
# 	16 : SmallAreaHighGrayLevelEmphasis [NUMERICAL]
# 	13 : LowGrayLevelZoneEmphasis [NUMERICAL]
# 	11 : ShortRunLowGrayLevelEmphasis [NUMERICAL]
# 	11 : RunPercentage [NUMERICAL]
# 	9 : Range [NUMERICAL]
# 	9 : Contrast.1 [NUMERICAL]
# 	8 : SmallDependenceLowGrayLevelEmphasis [NUMERICAL]
# 	8 : MCC [NUMERICAL]
# 	8 : LargeDependenceLowGrayLevelEmphasis [NUMERICAL]
# 	8 : Imc1 [NUMERICAL]
# 	7 : HighGrayLevelZoneEmphasis [NUMERICAL]
# 	7 : DifferenceVariance [NUMERICAL]
# 	6 : Kurtosis [NUMERICAL]
# 	6 : JointEnergy [NUMERICAL]
# 	6 : GrayLevelNonUniformity [NUMERICAL]
# 	6 : DependenceNonUniformity [NUMERICAL]
# 	5 : SmallAreaEmphasis [NUMERICAL]
# 	5 : LongRunLowGrayLevelEmphasis [NUMERICAL]
# 	5 : Entropy [NUMERICAL]
# 	5 : Autocorrelation [NUMERICAL]
# 	5 : 10Percentile [NUMERICAL]
# 	4 : ZonePercentage [NUMERICAL]
# 	4 : RunVariance [NUMERICAL]
# 	4 : RunLengthNonUniformityNormalized [NUMERICAL]
# 	4 : RootMeanSquared [NUMERICAL]
# 	4 : Minimum [NUMERICAL]
# 	4 : Mean [NUMERICAL]
# 	4 : MaximumProbability [NUMERICAL]
# 	4 : JointAverage [NUMERICAL]
# 	4 : Idm [NUMERICAL]
# 	4 : DependenceVariance [NUMERICAL]
# 	4 : Correlation [NUMERICAL]
# 	4 : Contrast [NUMERICAL]
# 	3 : Uniformity [NUMERICAL]
# 	3 : SumEntropy [NUMERICAL]
# 	3 : Strength [NUMERICAL]
# 	3 : SmallDependenceEmphasis [NUMERICAL]
# 	3 : SmallAreaLowGrayLevelEmphasis [NUMERICAL]
# 	3 : LowGrayLevelEmphasis [NUMERICAL]
# 	3 : LargeAreaLowGrayLevelEmphasis [NUMERICAL]
# 	3 : InverseVariance [NUMERICAL]
# 	3 : GrayLevelVariance.2 [NUMERICAL]
# 	3 : GrayLevelNonUniformity.1 [NUMERICAL]
# 	3 : DifferenceAverage [NUMERICAL]
# 	3 : DependenceNonUniformityNormalized [NUMERICAL]
# 	3 : ClusterProminence [NUMERICAL]
# 	2 : ZoneEntropy [NUMERICAL]
# 	2 : SumSquares [NUMERICAL]
# 	2 : SmallDependenceHighGrayLevelEmphasis [NUMERICAL]
# 	2 : SizeZoneNonUniformityNormalized [NUMERICAL]
# 	2 : SizeZoneNonUniformity [NUMERICAL]
# 	2 : RunEntropy [NUMERICAL]
# 	2 : MeanAbsoluteDeviation [NUMERICAL]
# 	2 : LongRunEmphasis [NUMERICAL]
# 	2 : LargeAreaEmphasis [NUMERICAL]
# 	2 : InterquartileRange [NUMERICAL]
# 	2 : GrayLevelVariance.1 [NUMERICAL]
# 	2 : GrayLevelNonUniformityNormalized [NUMERICAL]
# 	2 : DifferenceEntropy [NUMERICAL]
# 	2 : Complexity [NUMERICAL]
# 	1 : ZoneVariance [NUMERICAL]
# 	1 : TotalEnergy [NUMERICAL]
# 	1 : ShortRunEmphasis [NUMERICAL]
# 	1 : RunLengthNonUniformity [NUMERICAL]
# 	1 : RobustMeanAbsoluteDeviation [NUMERICAL]
# 	1 : LowGrayLevelRunEmphasis [NUMERICAL]
# 	1 : LargeDependenceEmphasis [NUMERICAL]
# 	1 : JointEntropy [NUMERICAL]
# 	1 : Imc2 [NUMERICAL]
# 	1 : Id [NUMERICAL]
# 	1 : HighGrayLevelRunEmphasis [NUMERICAL]
# 	1 : GrayLevelNonUniformityNormalized.1 [NUMERICAL]
# 	1 : ClusterTendency [NUMERICAL]
#
# Attribute in nodes with depth <= 5:
# 	147 : Idn [NUMERICAL]
# 	126 : LargeDependenceHighGrayLevelEmphasis [NUMERICAL]
# 	100 : LongRunHighGrayLevelEmphasis [NUMERICAL]
# 	76 : Coarseness [NUMERICAL]
# 	65 : Busyness [NUMERICAL]
# 	58 : Skewness [NUMERICAL]
# 	54 : Idmn [NUMERICAL]
# 	52 : LargeAreaHighGrayLevelEmphasis [NUMERICAL]
# 	47 : Median [NUMERICAL]
# 	43 : ClusterShade [NUMERICAL]
# 	42 : Maximum [NUMERICAL]
# 	36 : DependenceEntropy [NUMERICAL]
# 	34 : GrayLevelNonUniformity.2 [NUMERICAL]
# 	34 : 90Percentile [NUMERICAL]
# 	27 : SmallAreaHighGrayLevelEmphasis [NUMERICAL]
# 	20 : ShortRunLowGrayLevelEmphasis [NUMERICAL]
# 	20 : Range [NUMERICAL]
# 	20 : Imc1 [NUMERICAL]
# 	19 : Contrast.1 [NUMERICAL]
# 	18 : SmallDependenceLowGrayLevelEmphasis [NUMERICAL]
# 	18 : LargeDependenceLowGrayLevelEmphasis [NUMERICAL]
# 	17 : LowGrayLevelZoneEmphasis [NUMERICAL]
# 	16 : LargeAreaLowGrayLevelEmphasis [NUMERICAL]
# 	16 : DifferenceVariance [NUMERICAL]
# 	15 : ZoneEntropy [NUMERICAL]
# 	15 : Minimum [NUMERICAL]
# 	15 : MCC [NUMERICAL]
# 	13 : RunPercentage [NUMERICAL]
# 	13 : Kurtosis [NUMERICAL]
# 	13 : HighGrayLevelZoneEmphasis [NUMERICAL]
# 	12 : SmallAreaLowGrayLevelEmphasis [NUMERICAL]
# 	12 : LongRunLowGrayLevelEmphasis [NUMERICAL]
# 	12 : JointEnergy [NUMERICAL]
# 	12 : Entropy [NUMERICAL]
# 	12 : Autocorrelation [NUMERICAL]
# 	10 : SumEntropy [NUMERICAL]
# 	10 : GrayLevelNonUniformity [NUMERICAL]
# 	10 : DependenceVariance [NUMERICAL]
# 	10 : Correlation [NUMERICAL]
# 	10 : 10Percentile [NUMERICAL]
# 	9 : Mean [NUMERICAL]
# 	9 : InverseVariance [NUMERICAL]
# 	9 : DifferenceAverage [NUMERICAL]
# 	8 : SizeZoneNonUniformity [NUMERICAL]
# 	8 : DependenceNonUniformity [NUMERICAL]
# 	8 : Complexity [NUMERICAL]
# 	7 : ZonePercentage [NUMERICAL]
# 	7 : Strength [NUMERICAL]
# 	7 : SmallDependenceHighGrayLevelEmphasis [NUMERICAL]
# 	7 : RunVariance [NUMERICAL]
# 	7 : MeanAbsoluteDeviation [NUMERICAL]
# 	7 : MaximumProbability [NUMERICAL]
# 	7 : GrayLevelNonUniformity.1 [NUMERICAL]
# 	7 : Contrast [NUMERICAL]
# 	7 : ClusterProminence [NUMERICAL]
# 	6 : SmallAreaEmphasis [NUMERICAL]
# 	6 : SizeZoneNonUniformityNormalized [NUMERICAL]
# 	6 : JointAverage [NUMERICAL]
# 	6 : GrayLevelVariance.2 [NUMERICAL]
# 	5 : RunLengthNonUniformityNormalized [NUMERICAL]
# 	5 : RootMeanSquared [NUMERICAL]
# 	5 : Imc2 [NUMERICAL]
# 	5 : Idm [NUMERICAL]
# 	5 : DependenceNonUniformityNormalized [NUMERICAL]
# 	4 : Uniformity [NUMERICAL]
# 	4 : SmallDependenceEmphasis [NUMERICAL]
# 	4 : RunLengthNonUniformity [NUMERICAL]
# 	4 : LowGrayLevelEmphasis [NUMERICAL]
# 	4 : LongRunEmphasis [NUMERICAL]
# 	4 : InterquartileRange [NUMERICAL]
# 	4 : HighGrayLevelRunEmphasis [NUMERICAL]
# 	4 : GrayLevelNonUniformityNormalized.1 [NUMERICAL]
# 	4 : GrayLevelNonUniformityNormalized [NUMERICAL]
# 	3 : ZoneVariance [NUMERICAL]
# 	3 : ShortRunHighGrayLevelEmphasis [NUMERICAL]
# 	3 : RobustMeanAbsoluteDeviation [NUMERICAL]
# 	3 : LargeDependenceEmphasis [NUMERICAL]
# 	3 : JointEntropy [NUMERICAL]
# 	3 : GrayLevelVariance.1 [NUMERICAL]
# 	3 : Energy [NUMERICAL]
# 	3 : DifferenceEntropy [NUMERICAL]
# 	3 : ClusterTendency [NUMERICAL]
# 	2 : TotalEnergy [NUMERICAL]
# 	2 : SumSquares [NUMERICAL]
# 	2 : SumAverage [NUMERICAL]
# 	2 : ShortRunEmphasis [NUMERICAL]
# 	2 : RunEntropy [NUMERICAL]
# 	2 : LowGrayLevelRunEmphasis [NUMERICAL]
# 	2 : LargeAreaEmphasis [NUMERICAL]
# 	2 : HighGrayLevelEmphasis [NUMERICAL]
# 	1 : Variance [NUMERICAL]
# 	1 : Id [NUMERICAL]
#
# Condition type in nodes:
# 	1543 : HigherCondition
# Condition type in nodes with depth <= 0:
# 	62 : HigherCondition
# Condition type in nodes with depth <= 1:
# 	186 : HigherCondition
# Condition type in nodes with depth <= 2:
# 	419 : HigherCondition
# Condition type in nodes with depth <= 3:
# 	848 : HigherCondition
# Condition type in nodes with depth <= 5:
# 	1543 : HigherCondition
#
# Training logs:
# Number of iteration to final model: 62
# 	Iter:1 train-loss:1.233141 valid-loss:1.240480  train-accuracy:0.932200 valid-accuracy:0.910555
# 	Iter:2 train-loss:1.106856 valid-loss:1.122664  train-accuracy:0.948396 valid-accuracy:0.916930
# 	Iter:3 train-loss:1.000138 valid-loss:1.021941  train-accuracy:0.947540 valid-accuracy:0.924400
# 	Iter:4 train-loss:0.910089 valid-loss:0.939579  train-accuracy:0.947306 valid-accuracy:0.911263
# 	Iter:5 train-loss:0.833437 valid-loss:0.869390  train-accuracy:0.948007 valid-accuracy:0.914097
# 	Iter:6 train-loss:0.760964 valid-loss:0.805465  train-accuracy:0.949798 valid-accuracy:0.914097
# 	Iter:16 train-loss:0.368101 valid-loss:0.498248  train-accuracy:0.972032 valid-accuracy:0.924014
# 	Iter:26 train-loss:0.208898 valid-loss:0.390554  train-accuracy:0.984682 valid-accuracy:0.924722
# 	Iter:36 train-loss:0.128405 valid-loss:0.357157  train-accuracy:0.993303 valid-accuracy:0.926139
# 	Iter:46 train-loss:0.093701 valid-loss:0.343183  train-accuracy:0.994861 valid-accuracy:0.926848
# 	Iter:56 train-loss:0.071392 valid-loss:0.334629  train-accuracy:0.996574 valid-accuracy:0.937151
# 	Iter:66 train-loss:0.056396 valid-loss:0.326445  train-accuracy:0.997586 valid-accuracy:0.938567
# 	Iter:76 train-loss:0.045752 valid-loss:0.335808  train-accuracy:0.998443 valid-accuracy:0.939276
# 	Iter:86 train-loss:0.037930 valid-loss:0.347744  train-accuracy:0.998910 valid-accuracy:0.940692

# %%
# Model features
model.make_inspector().features()
# Out:
# ["10Percentile" (1; #0),
#  "90Percentile" (1; #1),
#  "Autocorrelation" (1; #2),
#  "Busyness" (1; #3),
#  "ClusterProminence" (1; #4),
#  "ClusterShade" (1; #5),
#  "ClusterTendency" (1; #6),
#  "Coarseness" (1; #7),
#  "Complexity" (1; #8),
#  "Contrast" (1; #9),
#  "Contrast.1" (1; #10),
#  "Correlation" (1; #11),
#  "DependenceEntropy" (1; #12),
#  "DependenceNonUniformity" (1; #13),
#  "DependenceNonUniformityNormalized" (1; #14),
#  "DependenceVariance" (1; #15),
#  "DifferenceAverage" (1; #16),
#  "DifferenceEntropy" (1; #17),
#  "DifferenceVariance" (1; #18),
#  "Energy" (1; #19),
#  "Entropy" (1; #20),
#  "GrayLevelNonUniformity" (1; #21),
#  "GrayLevelNonUniformity.1" (1; #22),
#  "GrayLevelNonUniformity.2" (1; #23),
#  "GrayLevelNonUniformityNormalized" (1; #24),
#  "GrayLevelNonUniformityNormalized.1" (1; #25),
#  "GrayLevelVariance" (1; #26),
#  "GrayLevelVariance.1" (1; #27),
#  "GrayLevelVariance.2" (1; #28),
#  "HighGrayLevelEmphasis" (1; #29),
#  "HighGrayLevelRunEmphasis" (1; #30),
#  "HighGrayLevelZoneEmphasis" (1; #31),
#  "Id" (1; #32),
#  "Idm" (1; #33),
#  "Idmn" (1; #34),
#  "Idn" (1; #35),
#  "Imc1" (1; #36),
#  "Imc2" (1; #37),
#  "InterquartileRange" (1; #38),
#  "InverseVariance" (1; #39),
#  "JointAverage" (1; #40),
#  "JointEnergy" (1; #41),
#  "JointEntropy" (1; #42),
#  "Kurtosis" (1; #43),
#  "LargeAreaEmphasis" (1; #44),
#  "LargeAreaHighGrayLevelEmphasis" (1; #45),
#  "LargeAreaLowGrayLevelEmphasis" (1; #46),
#  "LargeDependenceEmphasis" (1; #47),
#  "LargeDependenceHighGrayLevelEmphasis" (1; #48),
#  "LargeDependenceLowGrayLevelEmphasis" (1; #49),
#  "LongRunEmphasis" (1; #50),
#  "LongRunHighGrayLevelEmphasis" (1; #51),
#  "LongRunLowGrayLevelEmphasis" (1; #52),
#  "LowGrayLevelEmphasis" (1; #53),
#  "LowGrayLevelRunEmphasis" (1; #54),
#  "LowGrayLevelZoneEmphasis" (1; #55),
#  "MCC" (1; #56),
#  "Maximum" (1; #57),
#  "MaximumProbability" (1; #58),
#  "Mean" (1; #59),
#  "MeanAbsoluteDeviation" (1; #60),
#  "Median" (1; #61),
#  "Minimum" (1; #62),
#  "Range" (1; #63),
#  "RobustMeanAbsoluteDeviation" (1; #64),
#  "RootMeanSquared" (1; #65),
#  "RunEntropy" (1; #66),
#  "RunLengthNonUniformity" (1; #67),
#  "RunLengthNonUniformityNormalized" (1; #68),
#  "RunPercentage" (1; #69),
#  "RunVariance" (1; #70),
#  "ShortRunEmphasis" (1; #71),
#  "ShortRunHighGrayLevelEmphasis" (1; #72),
#  "ShortRunLowGrayLevelEmphasis" (1; #73),
#  "SizeZoneNonUniformity" (1; #74),
#  "SizeZoneNonUniformityNormalized" (1; #75),
#  "Skewness" (1; #76),
#  "SmallAreaEmphasis" (1; #77),
#  "SmallAreaHighGrayLevelEmphasis" (1; #78),
#  "SmallAreaLowGrayLevelEmphasis" (1; #79),
#  "SmallDependenceEmphasis" (1; #80),
#  "SmallDependenceHighGrayLevelEmphasis" (1; #81),
#  "SmallDependenceLowGrayLevelEmphasis" (1; #82),
#  "Strength" (1; #83),
#  "SumAverage" (1; #84),
#  "SumEntropy" (1; #85),
#  "SumSquares" (1; #86),
#  "TotalEnergy" (1; #87),
#  "Uniformity" (1; #88),
#  "Variance" (1; #89),
#  "ZoneEntropy" (1; #90),
#  "ZonePercentage" (1; #91),
#  "ZoneVariance" (1; #92)]

# %%
# Feature importance
model.make_inspector().variable_importances()
# Out:
# {'INV_MEAN_MIN_DEPTH': [("LongRunHighGrayLevelEmphasis" (1; #51),
#    0.27854762344873746),
#   ("LargeDependenceHighGrayLevelEmphasis" (1; #48), 0.265030865508489),
#   ("Idn" (1; #35), 0.2198666138489265),
#   ("Busyness" (1; #3), 0.20233110926991707),
#   ("Coarseness" (1; #7), 0.20160219603276028),
#   ("LargeAreaHighGrayLevelEmphasis" (1; #45), 0.18678197259534132),
#   ("Maximum" (1; #57), 0.18616132327556775),
#   ("Median" (1; #61), 0.18567019550025035),
#   ("DependenceEntropy" (1; #12), 0.18544492242399016),
#   ("Skewness" (1; #76), 0.18268023517645215),
#   ("ClusterShade" (1; #5), 0.18154051776264135),
#   ("SmallAreaHighGrayLevelEmphasis" (1; #78), 0.18142979942314708),
#   ("Idmn" (1; #34), 0.17962465812230505),
#   ("GrayLevelNonUniformity.2" (1; #23), 0.17799449820454316),
#   ("ShortRunLowGrayLevelEmphasis" (1; #73), 0.17796369132103726),
#   ("LowGrayLevelZoneEmphasis" (1; #55), 0.17768482896658744),
#   ("90Percentile" (1; #1), 0.17706032789518958),
#   ("MCC" (1; #56), 0.1764354263095636),
#   ("Range" (1; #63), 0.17630514971412906),
#   ("DependenceNonUniformity" (1; #13), 0.17583395717378938),
#   ("RunPercentage" (1; #69), 0.17549721244746425),
#   ("Contrast.1" (1; #10), 0.17542897407867605),
#   ("Imc1" (1; #36), 0.17496420054586956),
#   ("LargeDependenceLowGrayLevelEmphasis" (1; #49), 0.1748896605238899),
#   ("HighGrayLevelZoneEmphasis" (1; #31), 0.17438229362658883),
#   ("SmallDependenceLowGrayLevelEmphasis" (1; #82), 0.17412789808296827),
#   ("Strength" (1; #83), 0.17404452659798758),
#   ("DifferenceVariance" (1; #18), 0.17387919582193828),
#   ("Contrast" (1; #9), 0.17382095698936761),
#   ("Entropy" (1; #20), 0.17381222143251887),
#   ("LargeAreaLowGrayLevelEmphasis" (1; #46), 0.17377211103311738),
#   ("Autocorrelation" (1; #2), 0.17369368360702142),
#   ("JointAverage" (1; #40), 0.173620581140232),
#   ("Minimum" (1; #62), 0.17355799839290376),
#   ("GrayLevelNonUniformity" (1; #21), 0.17354479584235408),
#   ("LowGrayLevelEmphasis" (1; #53), 0.17353277634218497),
#   ("Kurtosis" (1; #43), 0.1735236326618106),
#   ("InverseVariance" (1; #39), 0.17351109623032554),
#   ("RootMeanSquared" (1; #65), 0.1735064897500467),
#   ("SmallAreaLowGrayLevelEmphasis" (1; #79), 0.1734608861848179),
#   ("LongRunLowGrayLevelEmphasis" (1; #52), 0.17344480807841545),
#   ("ZoneEntropy" (1; #90), 0.17337096233100718),
#   ("JointEnergy" (1; #41), 0.1733642010485906),
#   ("RunVariance" (1; #70), 0.17330131236767315),
#   ("10Percentile" (1; #0), 0.17328968017583438),
#   ("DifferenceAverage" (1; #16), 0.17327004679624944),
#   ("Correlation" (1; #11), 0.17323810527181951),
#   ("MeanAbsoluteDeviation" (1; #60), 0.17321232589026256),
#   ("SumEntropy" (1; #85), 0.1731295084630303),
#   ("MaximumProbability" (1; #58), 0.17312657943783474),
#   ("DependenceVariance" (1; #15), 0.17311502533720663),
#   ("Complexity" (1; #8), 0.1731132809221498),
#   ("ClusterProminence" (1; #4), 0.17309745272335922),
#   ("Uniformity" (1; #88), 0.17307911717834037),
#   ("SmallAreaEmphasis" (1; #77), 0.17304695574577783),
#   ("ZonePercentage" (1; #91), 0.17302960941775983),
#   ("RunLengthNonUniformityNormalized" (1; #68), 0.17302303130156843),
#   ("GrayLevelNonUniformity.1" (1; #22), 0.17301400472839348),
#   ("SizeZoneNonUniformity" (1; #74), 0.17300350553456453),
#   ("LargeDependenceEmphasis" (1; #47), 0.17296542511169558),
#   ("Idm" (1; #33), 0.17295499507198747),
#   ("DependenceNonUniformityNormalized" (1; #14), 0.17291735861900262),
#   ("SmallDependenceHighGrayLevelEmphasis" (1; #81), 0.17291103096509428),
#   ("ZoneVariance" (1; #92), 0.17290523026115534),
#   ("GrayLevelVariance.2" (1; #28), 0.17289046648069195),
#   ("Mean" (1; #59), 0.1728510077974301),
#   ("SizeZoneNonUniformityNormalized" (1; #75), 0.17282055189015846),
#   ("GrayLevelVariance.1" (1; #27), 0.17279683518503863),
#   ("SmallDependenceEmphasis" (1; #80), 0.1727583428102975),
#   ("InterquartileRange" (1; #38), 0.17275790773664226),
#   ("Imc2" (1; #37), 0.17272676516170277),
#   ("GrayLevelNonUniformityNormalized" (1; #24), 0.17268037685308163),
#   ("GrayLevelNonUniformityNormalized.1" (1; #25), 0.1726507399387967),
#   ("DifferenceEntropy" (1; #17), 0.1726393180857784),
#   ("SumSquares" (1; #86), 0.17262898933922607),
#   ("RunEntropy" (1; #66), 0.1726199291326796),
#   ("RobustMeanAbsoluteDeviation" (1; #64), 0.17261022798187858),
#   ("ClusterTendency" (1; #6), 0.17260461160224694),
#   ("LongRunEmphasis" (1; #50), 0.17257792007458958),
#   ("LargeAreaEmphasis" (1; #44), 0.1725758166598258),
#   ("HighGrayLevelRunEmphasis" (1; #30), 0.17254767965437673),
#   ("RunLengthNonUniformity" (1; #67), 0.17254190730515334),
#   ("TotalEnergy" (1; #87), 0.17253291515565775),
#   ("ShortRunEmphasis" (1; #71), 0.17252995878580824),
#   ("Id" (1; #32), 0.17252456177703895),
#   ("JointEntropy" (1; #42), 0.17252146754629957),
#   ("Energy" (1; #19), 0.1725200609416848),
#   ("ShortRunHighGrayLevelEmphasis" (1; #72), 0.17250649628504044),
#   ("LowGrayLevelRunEmphasis" (1; #54), 0.1724856017543946),
#   ("HighGrayLevelEmphasis" (1; #29), 0.17248148877189937),
#   ("SumAverage" (1; #84), 0.1724743538970685),
#   ("Variance" (1; #89), 0.1724434048181613)],
#  'SUM_SCORE': [("LongRunHighGrayLevelEmphasis" (1; #51), 4710.757660183339),
#   ("LargeDependenceHighGrayLevelEmphasis" (1; #48), 905.0263120669321),
#   ("Idn" (1; #35), 674.3946930116507),
#   ("Busyness" (1; #3), 476.0770897478936),
#   ("Coarseness" (1; #7), 245.6526537673115),
#   ("GrayLevelNonUniformity.2" (1; #23), 220.8577347105552),
#   ("Maximum" (1; #57), 130.40941836996495),
#   ("Idmn" (1; #34), 125.54128303248261),
#   ("Skewness" (1; #76), 115.73833803809673),
#   ("LargeAreaHighGrayLevelEmphasis" (1; #45), 101.95800736428205),
#   ("Median" (1; #61), 100.07618531656813),
#   ("Kurtosis" (1; #43), 84.37363387278691),
#   ("DependenceEntropy" (1; #12), 75.7967348676996),
#   ("Imc1" (1; #36), 59.41912892338751),
#   ("LongRunLowGrayLevelEmphasis" (1; #52), 57.89542780961012),
#   ("Contrast.1" (1; #10), 51.39275165910783),
#   ("Range" (1; #63), 44.66191692892219),
#   ("90Percentile" (1; #1), 44.39795920670139),
#   ("SmallAreaHighGrayLevelEmphasis" (1; #78), 40.13895766431354),
#   ("RunPercentage" (1; #69), 31.225717476867874),
#   ("LowGrayLevelZoneEmphasis" (1; #55), 30.940542787299698),
#   ("SmallDependenceLowGrayLevelEmphasis" (1; #82), 29.64803451197099),
#   ("ShortRunLowGrayLevelEmphasis" (1; #73), 27.53885067339844),
#   ("Mean" (1; #59), 27.29052431488333),
#   ("ZonePercentage" (1; #91), 26.488868229257076),
#   ("ClusterShade" (1; #5), 25.515133987566717),
#   ("Autocorrelation" (1; #2), 25.454505032499718),
#   ("DependenceNonUniformityNormalized" (1; #14), 23.42026750025245),
#   ("LargeDependenceLowGrayLevelEmphasis" (1; #49), 23.389613503749466),
#   ("DifferenceVariance" (1; #18), 23.040545425909837),
#   ("Minimum" (1; #62), 22.437980786081447),
#   ("RunLengthNonUniformityNormalized" (1; #68), 21.32311807260777),
#   ("HighGrayLevelZoneEmphasis" (1; #31), 21.311979720996156),
#   ("MeanAbsoluteDeviation" (1; #60), 18.039311271079637),
#   ("DependenceNonUniformity" (1; #13), 17.287326547267963),
#   ("GrayLevelNonUniformity" (1; #21), 16.940224193440518),
#   ("JointEnergy" (1; #41), 16.34846644610268),
#   ("SizeZoneNonUniformity" (1; #74), 16.226153852113402),
#   ("MCC" (1; #56), 16.0334196302358),
#   ("LargeAreaLowGrayLevelEmphasis" (1; #46), 15.30129864747005),
#   ("ClusterProminence" (1; #4), 14.590311420511284),
#   ("10Percentile" (1; #0), 14.149213164835636),
#   ("ZoneEntropy" (1; #90), 14.072624901061747),
#   ("Uniformity" (1; #88), 12.272568570046591),
#   ("ZoneVariance" (1; #92), 11.56677841171936),
#   ("DifferenceAverage" (1; #16), 10.694763576641058),
#   ("LargeAreaEmphasis" (1; #44), 10.64349531601499),
#   ("Entropy" (1; #20), 9.475449485713451),
#   ("GrayLevelNonUniformityNormalized" (1; #24), 8.993141295664925),
#   ("Imc2" (1; #37), 8.792057750476355),
#   ("Strength" (1; #83), 8.121526576323996),
#   ("SmallAreaLowGrayLevelEmphasis" (1; #79), 8.114353094035588),
#   ("SizeZoneNonUniformityNormalized" (1; #75), 7.8643519902002454),
#   ("SmallDependenceHighGrayLevelEmphasis" (1; #81), 7.483508302913874),
#   ("Correlation" (1; #11), 7.480842731490343),
#   ("GrayLevelVariance.2" (1; #28), 7.236700706794125),
#   ("RunEntropy" (1; #66), 7.19996621331509),
#   ("LongRunEmphasis" (1; #50), 6.800190327389486),
#   ("SmallAreaEmphasis" (1; #77), 6.496843128310924),
#   ("ClusterTendency" (1; #6), 6.4404589842123565),
#   ("SumEntropy" (1; #85), 6.035543414007527),
#   ("Contrast" (1; #9), 5.657302405573507),
#   ("Energy" (1; #19), 5.516677128979756),
#   ("RunVariance" (1; #70), 5.271218156816436),
#   ("Idm" (1; #33), 4.981285241022662),
#   ("Complexity" (1; #8), 4.313080644221947),
#   ("RootMeanSquared" (1; #65), 3.4715946685649195),
#   ("InterquartileRange" (1; #38), 2.8538848373414414),
#   ("DifferenceEntropy" (1; #17), 2.5403489882752144),
#   ("GrayLevelNonUniformityNormalized.1" (1; #25), 2.5202841759829675),
#   ("GrayLevelNonUniformity.1" (1; #22), 2.3306007230211385),
#   ("SumAverage" (1; #84), 2.0319099400575977),
#   ("DependenceVariance" (1; #15), 1.7842141367210773),
#   ("GrayLevelVariance.1" (1; #27), 1.7451215631321155),
#   ("InverseVariance" (1; #39), 1.601193185985576),
#   ("JointAverage" (1; #40), 1.490727842555759),
#   ("LowGrayLevelRunEmphasis" (1; #54), 1.4811279309031289),
#   ("MaximumProbability" (1; #58), 1.4654956827380299),
#   ("HighGrayLevelEmphasis" (1; #29), 1.4540270028957742),
#   ("SumSquares" (1; #86), 1.192695278379009),
#   ("HighGrayLevelRunEmphasis" (1; #30), 0.7941025521813972),
#   ("TotalEnergy" (1; #87), 0.7736358270395354),
#   ("ShortRunHighGrayLevelEmphasis" (1; #72), 0.7370135681213847),
#   ("RunLengthNonUniformity" (1; #67), 0.665530105620561),
#   ("LargeDependenceEmphasis" (1; #47), 0.529058030825078),
#   ("SmallDependenceEmphasis" (1; #80), 0.5140393812661688),
#   ("RobustMeanAbsoluteDeviation" (1; #64), 0.4731210136502167),
#   ("LowGrayLevelEmphasis" (1; #53), 0.24911274135843262),
#   ("ShortRunEmphasis" (1; #71), 0.21816553274522432),
#   ("Id" (1; #32), 0.1290510633208672),
#   ("JointEntropy" (1; #42), 0.10307549431489166),
#   ("Variance" (1; #89), 0.05988698434757764)],
#  'NUM_AS_ROOT': [("LongRunHighGrayLevelEmphasis" (1; #51), 27.0),
#   ("LargeDependenceHighGrayLevelEmphasis" (1; #48), 14.0),
#   ("Busyness" (1; #3), 7.0),
#   ("Coarseness" (1; #7), 5.0),
#   ("DependenceEntropy" (1; #12), 3.0),
#   ("Maximum" (1; #57), 3.0),
#   ("Median" (1; #61), 2.0),
#   ("MCC" (1; #56), 1.0)],
#  'NUM_NODES': [("Idn" (1; #35), 147.0),
#   ("LargeDependenceHighGrayLevelEmphasis" (1; #48), 126.0),
#   ("LongRunHighGrayLevelEmphasis" (1; #51), 100.0),
#   ("Coarseness" (1; #7), 76.0),
#   ("Busyness" (1; #3), 65.0),
#   ("Skewness" (1; #76), 58.0),
#   ("Idmn" (1; #34), 54.0),
#   ("LargeAreaHighGrayLevelEmphasis" (1; #45), 52.0),
#   ("Median" (1; #61), 47.0),
#   ("ClusterShade" (1; #5), 43.0),
#   ("Maximum" (1; #57), 42.0),
#   ("DependenceEntropy" (1; #12), 36.0),
#   ("90Percentile" (1; #1), 34.0),
#   ("GrayLevelNonUniformity.2" (1; #23), 34.0),
#   ("SmallAreaHighGrayLevelEmphasis" (1; #78), 27.0),
#   ("Imc1" (1; #36), 20.0),
#   ("Range" (1; #63), 20.0),
#   ("ShortRunLowGrayLevelEmphasis" (1; #73), 20.0),
#   ("Contrast.1" (1; #10), 19.0),
#   ("LargeDependenceLowGrayLevelEmphasis" (1; #49), 18.0),
#   ("SmallDependenceLowGrayLevelEmphasis" (1; #82), 18.0),
#   ("LowGrayLevelZoneEmphasis" (1; #55), 17.0),
#   ("DifferenceVariance" (1; #18), 16.0),
#   ("LargeAreaLowGrayLevelEmphasis" (1; #46), 16.0),
#   ("MCC" (1; #56), 15.0),
#   ("Minimum" (1; #62), 15.0),
#   ("ZoneEntropy" (1; #90), 15.0),
#   ("HighGrayLevelZoneEmphasis" (1; #31), 13.0),
#   ("Kurtosis" (1; #43), 13.0),
#   ("RunPercentage" (1; #69), 13.0),
#   ("Autocorrelation" (1; #2), 12.0),
#   ("Entropy" (1; #20), 12.0),
#   ("JointEnergy" (1; #41), 12.0),
#   ("LongRunLowGrayLevelEmphasis" (1; #52), 12.0),
#   ("SmallAreaLowGrayLevelEmphasis" (1; #79), 12.0),
#   ("10Percentile" (1; #0), 10.0),
#   ("Correlation" (1; #11), 10.0),
#   ("DependenceVariance" (1; #15), 10.0),
#   ("GrayLevelNonUniformity" (1; #21), 10.0),
#   ("SumEntropy" (1; #85), 10.0),
#   ("DifferenceAverage" (1; #16), 9.0),
#   ("InverseVariance" (1; #39), 9.0),
#   ("Mean" (1; #59), 9.0),
#   ("Complexity" (1; #8), 8.0),
#   ("DependenceNonUniformity" (1; #13), 8.0),
#   ("SizeZoneNonUniformity" (1; #74), 8.0),
#   ("ClusterProminence" (1; #4), 7.0),
#   ("Contrast" (1; #9), 7.0),
#   ("GrayLevelNonUniformity.1" (1; #22), 7.0),
#   ("MaximumProbability" (1; #58), 7.0),
#   ("MeanAbsoluteDeviation" (1; #60), 7.0),
#   ("RunVariance" (1; #70), 7.0),
#   ("SmallDependenceHighGrayLevelEmphasis" (1; #81), 7.0),
#   ("Strength" (1; #83), 7.0),
#   ("ZonePercentage" (1; #91), 7.0),
#   ("GrayLevelVariance.2" (1; #28), 6.0),
#   ("JointAverage" (1; #40), 6.0),
#   ("SizeZoneNonUniformityNormalized" (1; #75), 6.0),
#   ("SmallAreaEmphasis" (1; #77), 6.0),
#   ("DependenceNonUniformityNormalized" (1; #14), 5.0),
#   ("Idm" (1; #33), 5.0),
#   ("Imc2" (1; #37), 5.0),
#   ("RootMeanSquared" (1; #65), 5.0),
#   ("RunLengthNonUniformityNormalized" (1; #68), 5.0),
#   ("GrayLevelNonUniformityNormalized" (1; #24), 4.0),
#   ("GrayLevelNonUniformityNormalized.1" (1; #25), 4.0),
#   ("HighGrayLevelRunEmphasis" (1; #30), 4.0),
#   ("InterquartileRange" (1; #38), 4.0),
#   ("LongRunEmphasis" (1; #50), 4.0),
#   ("LowGrayLevelEmphasis" (1; #53), 4.0),
#   ("RunLengthNonUniformity" (1; #67), 4.0),
#   ("SmallDependenceEmphasis" (1; #80), 4.0),
#   ("Uniformity" (1; #88), 4.0),
#   ("ClusterTendency" (1; #6), 3.0),
#   ("DifferenceEntropy" (1; #17), 3.0),
#   ("Energy" (1; #19), 3.0),
#   ("GrayLevelVariance.1" (1; #27), 3.0),
#   ("JointEntropy" (1; #42), 3.0),
#   ("LargeDependenceEmphasis" (1; #47), 3.0),
#   ("RobustMeanAbsoluteDeviation" (1; #64), 3.0),
#   ("ShortRunHighGrayLevelEmphasis" (1; #72), 3.0),
#   ("ZoneVariance" (1; #92), 3.0),
#   ("HighGrayLevelEmphasis" (1; #29), 2.0),
#   ("LargeAreaEmphasis" (1; #44), 2.0),
#   ("LowGrayLevelRunEmphasis" (1; #54), 2.0),
#   ("RunEntropy" (1; #66), 2.0),
#   ("ShortRunEmphasis" (1; #71), 2.0),
#   ("SumAverage" (1; #84), 2.0),
#   ("SumSquares" (1; #86), 2.0),
#   ("TotalEnergy" (1; #87), 2.0),
#   ("Id" (1; #32), 1.0),
#   ("Variance" (1; #89), 1.0)]}

# %%
# Model self evaluation
model.make_inspector().evaluation()
# Out:
# Evaluation(num_examples=None, accuracy=0.9392756819725037, loss=0.32498061656951904, rmse=None, ndcg=None, aucs=None, auuc=None, qini=None)

# %%
logs = model.make_inspector().training_logs()

plt.figure(figsize=(12, 4))
plt.subplot(1, 2, 1)
plt.plot([log.num_trees for log in logs], [log.evaluation.accuracy for log in logs])
plt.xlabel("Number of trees")
plt.ylabel("Accuracy (out-of-bag)")
plt.subplot(1, 2, 2)
plt.plot([log.num_trees for log in logs], [log.evaluation.loss for log in logs])
plt.xlabel("Number of trees")
plt.ylabel("Logloss (out-of-bag)")
plt.show()

# %% [markdown]
# Calculate the score of our hold-out validation dataset

# %%
predictions = model.predict(val_ds)
y_true      = validation_data["label"]

from sklearn.metrics import roc_auc_score
ROC_AUC = roc_auc_score(y_true, predictions)
print("The ROC AUC score is %.5f" % ROC_AUC )
# Out:
# 1/2 [==============>...............] - ETA: 0s
# 2/2 [==============================] - 0s 4ms/step
# The ROC AUC score is 0.99721

# %%
# Compute binary classification metrics with sklearn
import numpy as np
from sklearn.metrics import (
    accuracy_score,
    precision_score,
    recall_score,
    f1_score,
    roc_auc_score,
    average_precision_score,
    confusion_matrix,
    classification_report,
    matthews_corrcoef,
    log_loss,
    brier_score_loss,
)

# Get predictions (probabilities or class labels)
preds = model.predict(test_ds)
# If model outputs probabilities, convert to labels by threshold 0.5
if preds.ndim == 2:
    # For TFDF classification, preds may be class probabilities with shape (N, 2)
    if preds.shape[1] == 2:
        pos_probs = preds[:, 1]
    else:
        # If single-probability column (positive class)
        pos_probs = preds[:, -1]
    y_pred = (pos_probs >= 0.5).astype(int)
else:
    # Already class labels
    y_pred = preds.astype(int)
    pos_probs = None

# Ground truth labels (must be 0/1 integers)
y_true = test_data["label"].astype(int).to_numpy()

# Core metrics
metrics = {}
metrics["accuracy"] = accuracy_score(y_true, y_pred)
metrics["precision"] = precision_score(y_true, y_pred, zero_division=0)
metrics["recall"] = recall_score(y_true, y_pred, zero_division=0)
metrics["f1"] = f1_score(y_true, y_pred, zero_division=0)
metrics["mcc"] = matthews_corrcoef(y_true, y_pred)

# Probabilistic metrics (only if we have probabilities)
if pos_probs is not None:
    metrics["roc_auc"] = roc_auc_score(y_true, pos_probs)
    metrics["pr_auc"] = average_precision_score(y_true, pos_probs)
    metrics["log_loss"] = log_loss(y_true, pos_probs, labels=[0,1])
    metrics["brier_score"] = brier_score_loss(y_true, pos_probs)

# Confusion matrix and detailed report
cm = confusion_matrix(y_true, y_pred, labels=[0,1])
report = classification_report(y_true, y_pred, digits=4)

print("Sklearn binary metrics:")
for k, v in metrics.items():
    print(f"{k}: {v:.4f}")
print("\nConfusion matrix:\n", cm)
print("\nClassification report:\n", report)
# Out:
# 1/3 [=========>....................] - ETA: 0s
# 3/3 [==============================] - 0s 15ms/step
# Sklearn binary metrics:
# accuracy: 0.9641
# precision: 0.8033
# recall: 0.8458
# f1: 0.8240
# mcc: 0.8044
# roc_auc: 0.9821
# pr_auc: 0.9086
# log_loss: 0.1064
# brier_score: 0.0282
#
# Confusion matrix:
#  [[2009   47]
#  [  35  192]]
#
# Classification report:
#                precision    recall  f1-score   support
#
#            0     0.9829    0.9771    0.9800      2056
#            1     0.8033    0.8458    0.8240       227
#
#     accuracy                         0.9641      2283
#    macro avg     0.8931    0.9115    0.9020      2283
# weighted avg     0.9650    0.9641    0.9645      2283
