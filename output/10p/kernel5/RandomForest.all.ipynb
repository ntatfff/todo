# %%
# Import packages and modules
import numpy  as np
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow_decision_forests as tfdf

from sklearn.model_selection import train_test_split
# Out:
# 2026-09-11 08:22:43.619265: I tensorflow/core/util/port.cc:113] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2026-09-11 08:22:43.658929: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2026-09-11 08:22:47.913085: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
# Check the version of TensorFlow Decision Forests
print("Found TensorFlow Decision Forests v" + tfdf.__version__)
# Out:
# Found TensorFlow Decision Forests v1.9.1

# %%
datasetPath = "dataset/10p/all/kernel3/"

# %%
# Parameters
datasetPath = "dataset/10p/all/kernel5/"

# %%
# train/validation/test = 70/10/20
train_data = pd.read_csv(f"{datasetPath}dataset.train.csv")
validation_data = pd.read_csv(f"{datasetPath}dataset.validation.csv")
test_data = pd.read_csv(f"{datasetPath}dataset.test.csv")

# %%
from sklearn.utils.class_weight import compute_class_weight

# tinh class weight tren tap train
classes = np.array([0, 1])
weights = compute_class_weight(class_weight="balanced", classes=classes, y=train_data["label"])
class_weight = {0: weights[0], 1: weights[1]}

# gan sample_weight cho tung dong
train_data["sample_weight"] = train_data["label"].map(class_weight)
validation_data["sample_weight"] = validation_data["label"].map(class_weight)
test_data["sample_weight"] = test_data["label"].map(class_weight)

# Convert the dataset into a TensorFlow dataset.
train_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    train_data, label="label", weight="sample_weight"
)         
val_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    validation_data, label="label", weight="sample_weight"
)
test_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    test_data, label="label", weight="sample_weight"
)
# Out:
# 2026-09-11 08:22:59.739107: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:984] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2026-09-11 08:22:59.740697: W tensorflow/core/common_runtime/gpu/gpu_device.cc:2251] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...

# %%
import keras

# %%
# %%time

# Train a Random Forest model.
model = tfdf.keras.RandomForestModel()

# Add evaluation metrics
model.compile(
    metrics=["accuracy"]
)
model.fit(x=train_ds)

# # Train a Gradient Boosted Trees model.
# model = tfdf.keras.GradientBoostedTreesModel(num_trees=1500)
# model.fit(train_ds)
# Out:
# Use /tmp/tmppvb3jhj8 as temporary training directory
# Reading training dataset...
# Training dataset read in 0:00:03.263861. Found 7617 examples.
# Training model...
# Model trained in 0:00:00.713381
# Compiling model...
# [INFO 26-09-11 08:23:03.9209 UTC kernel.cc:1233] Loading model from path /tmp/tmppvb3jhj8/model/ with prefix 4376c70a486e4ab0
# [INFO 26-09-11 08:23:03.9852 UTC decision_forest.cc:734] Model loaded with 300 root(s), 58254 node(s), and 93 input feature(s).
# [INFO 26-09-11 08:23:03.9853 UTC abstract_model.cc:1362] Engine "RandomForestOptPred" built
# [INFO 26-09-11 08:23:03.9853 UTC kernel.cc:1061] Use fast generic engine
# Model compiled.
# CPU times: user 12.9 s, sys: 134 ms, total: 13.1 s
# Wall time: 7.5 s

# %%
# Evaluate the model
evaluate = model.evaluate(val_ds, return_dict=True)
print()

for name, value in evaluate.items():
    print(f"{name}: {value:.4f}")
# Out:
# WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 1/2 [==============>...............] - ETA: 2s - loss: 0.0000e+00 - accuracy: 0.9930
# 2/2 [==============================] - 3s 10ms/step - loss: 0.0000e+00 - accuracy: 0.9916
# loss: 0.0000
# accuracy: 0.9916

# %%
# Model Summary
model.summary()
# Out:
# Model: "random_forest_model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
# =================================================================
# Total params: 1 (1.00 Byte)
# Trainable params: 0 (0.00 Byte)
# Non-trainable params: 1 (1.00 Byte)
# _________________________________________________________________
# Type: "RANDOM_FOREST"
# Task: CLASSIFICATION
# Label: "__LABEL"
#
# Input Features (93):
# 	10Percentile
# 	90Percentile
# 	Autocorrelation
# 	Busyness
# 	ClusterProminence
# 	ClusterShade
# 	ClusterTendency
# 	Coarseness
# 	Complexity
# 	Contrast
# 	Contrast.1
# 	Correlation
# 	DependenceEntropy
# 	DependenceNonUniformity
# 	DependenceNonUniformityNormalized
# 	DependenceVariance
# 	DifferenceAverage
# 	DifferenceEntropy
# 	DifferenceVariance
# 	Energy
# 	Entropy
# 	GrayLevelNonUniformity
# 	GrayLevelNonUniformity.1
# 	GrayLevelNonUniformity.2
# 	GrayLevelNonUniformityNormalized
# 	GrayLevelNonUniformityNormalized.1
# 	GrayLevelVariance
# 	GrayLevelVariance.1
# 	GrayLevelVariance.2
# 	HighGrayLevelEmphasis
# 	HighGrayLevelRunEmphasis
# 	HighGrayLevelZoneEmphasis
# 	Id
# 	Idm
# 	Idmn
# 	Idn
# 	Imc1
# 	Imc2
# 	InterquartileRange
# 	InverseVariance
# 	JointAverage
# 	JointEnergy
# 	JointEntropy
# 	Kurtosis
# 	LargeAreaEmphasis
# 	LargeAreaHighGrayLevelEmphasis
# 	LargeAreaLowGrayLevelEmphasis
# 	LargeDependenceEmphasis
# 	LargeDependenceHighGrayLevelEmphasis
# 	LargeDependenceLowGrayLevelEmphasis
# 	LongRunEmphasis
# 	LongRunHighGrayLevelEmphasis
# 	LongRunLowGrayLevelEmphasis
# 	LowGrayLevelEmphasis
# 	LowGrayLevelRunEmphasis
# 	LowGrayLevelZoneEmphasis
# 	MCC
# 	Maximum
# 	MaximumProbability
# 	Mean
# 	MeanAbsoluteDeviation
# 	Median
# 	Minimum
# 	Range
# 	RobustMeanAbsoluteDeviation
# 	RootMeanSquared
# 	RunEntropy
# 	RunLengthNonUniformity
# 	RunLengthNonUniformityNormalized
# 	RunPercentage
# 	RunVariance
# 	ShortRunEmphasis
# 	ShortRunHighGrayLevelEmphasis
# 	ShortRunLowGrayLevelEmphasis
# 	SizeZoneNonUniformity
# 	SizeZoneNonUniformityNormalized
# 	Skewness
# 	SmallAreaEmphasis
# 	SmallAreaHighGrayLevelEmphasis
# 	SmallAreaLowGrayLevelEmphasis
# 	SmallDependenceEmphasis
# 	SmallDependenceHighGrayLevelEmphasis
# 	SmallDependenceLowGrayLevelEmphasis
# 	Strength
# 	SumAverage
# 	SumEntropy
# 	SumSquares
# 	TotalEnergy
# 	Uniformity
# 	Variance
# 	ZoneEntropy
# 	ZonePercentage
# 	ZoneVariance
#
# Trained with weights
#
# Variable Importance: INV_MEAN_MIN_DEPTH:
#     1.         "LongRunHighGrayLevelEmphasis"  0.134482 ################
#     2. "LargeDependenceHighGrayLevelEmphasis"  0.129332 #############
#     3.                             "Busyness"  0.126484 ###########
#     4.             "GrayLevelNonUniformity.2"  0.123383 #########
#     5.                         "90Percentile"  0.121983 ########
#     6.                           "Coarseness"  0.121962 ########
#     7.                           "SumAverage"  0.120927 ########
#     8.                               "Median"  0.120761 ########
#     9.                      "Autocorrelation"  0.120459 #######
#    10.                          "TotalEnergy"  0.119762 #######
#    11.                "HighGrayLevelEmphasis"  0.118949 #######
#    12.                         "JointAverage"  0.118704 ######
#    13.                                 "Mean"  0.118113 ######
#    14.            "HighGrayLevelZoneEmphasis"  0.117820 ######
#    15.                               "Energy"  0.116755 #####
#    16.                              "Maximum"  0.116359 #####
#    17.                                 "Imc1"  0.116103 #####
#    18.                      "RootMeanSquared"  0.115494 #####
#    19.       "LargeAreaHighGrayLevelEmphasis"  0.115351 ####
#    20.                                  "Idn"  0.114797 ####
#    21.                    "DependenceEntropy"  0.114515 ####
#    22.                             "Skewness"  0.113633 ###
#    23.       "SmallAreaHighGrayLevelEmphasis"  0.113343 ###
#    24.        "ShortRunHighGrayLevelEmphasis"  0.113290 ###
#    25.                                 "Idmn"  0.112792 ###
#    26.    "DependenceNonUniformityNormalized"  0.112786 ###
#    27. "SmallDependenceHighGrayLevelEmphasis"  0.112187 ###
#    28.                      "InverseVariance"  0.112052 ###
#    29.             "HighGrayLevelRunEmphasis"  0.111837 ##
#    30.                         "ClusterShade"  0.111788 ##
#    31.              "DependenceNonUniformity"  0.111717 ##
#    32.                          "Correlation"  0.111643 ##
#    33.                                 "Imc2"  0.111621 ##
#    34.         "ShortRunLowGrayLevelEmphasis"  0.110919 ##
#    35.                 "LowGrayLevelEmphasis"  0.110505 ##
#    36.  "SmallDependenceLowGrayLevelEmphasis"  0.110400 ##
#    37.          "LongRunLowGrayLevelEmphasis"  0.110382 ##
#    38.                                  "MCC"  0.110064 #
#    39.  "LargeDependenceLowGrayLevelEmphasis"  0.109692 #
#    40.              "SmallDependenceEmphasis"  0.109578 #
#    41.                             "Strength"  0.109478 #
#    42.                           "Uniformity"  0.109413 #
#    43.                           "Contrast.1"  0.109393 #
#    44.                             "Kurtosis"  0.109319 #
#    45.              "LowGrayLevelRunEmphasis"  0.109290 #
#    46.                "SizeZoneNonUniformity"  0.109277 #
#    47.                              "Minimum"  0.109267 #
#    48.                           "SumEntropy"  0.109183 #
#    49.                                "Range"  0.108950 #
#    50.               "GrayLevelNonUniformity"  0.108929 #
#    51.             "LowGrayLevelZoneEmphasis"  0.108805 #
#    52.     "RunLengthNonUniformityNormalized"  0.108752 #
#    53.        "SmallAreaLowGrayLevelEmphasis"  0.108745 #
#    54.        "LargeAreaLowGrayLevelEmphasis"  0.108735 #
#    55.                         "10Percentile"  0.108696 #
#    56.   "GrayLevelNonUniformityNormalized.1"  0.108658 #
#    57.                             "Contrast"  0.108657 #
#    58.                          "ZoneEntropy"  0.108602 #
#    59.                   "DifferenceVariance"  0.108531 #
#    60.                       "ZonePercentage"  0.108458
#    61.                      "LongRunEmphasis"  0.108416
#    62.                   "DependenceVariance"  0.108374
#    63.                          "RunVariance"  0.108358
#    64.               "RunLengthNonUniformity"  0.108240
#    65.                           "RunEntropy"  0.108230
#    66.                           "Complexity"  0.108198
#    67.                                  "Idm"  0.108186
#    68.                                   "Id"  0.108134
#    69.                              "Entropy"  0.108049
#    70.                  "GrayLevelVariance.2"  0.107997
#    71.             "GrayLevelNonUniformity.1"  0.107977
#    72.                          "JointEnergy"  0.107962
#    73.     "GrayLevelNonUniformityNormalized"  0.107951
#    74.              "LargeDependenceEmphasis"  0.107857
#    75.                   "MaximumProbability"  0.107841
#    76.                    "ClusterProminence"  0.107748
#    77.      "SizeZoneNonUniformityNormalized"  0.107732
#    78.                    "DifferenceAverage"  0.107666
#    79.                     "ShortRunEmphasis"  0.107665
#    80.                        "RunPercentage"  0.107620
#    81.                         "ZoneVariance"  0.107445
#    82.                   "InterquartileRange"  0.107423
#    83.                    "SmallAreaEmphasis"  0.107417
#    84.                    "DifferenceEntropy"  0.107392
#    85.                    "LargeAreaEmphasis"  0.107387
#    86.                             "Variance"  0.107375
#    87.                      "ClusterTendency"  0.107368
#    88.          "RobustMeanAbsoluteDeviation"  0.107353
#    89.                  "GrayLevelVariance.1"  0.107308
#    90.                           "SumSquares"  0.107159
#    91.                    "GrayLevelVariance"  0.106999
#    92.                         "JointEntropy"  0.106946
#    93.                "MeanAbsoluteDeviation"  0.106782
#
# Variable Importance: NUM_AS_ROOT:
#     1.         "LongRunHighGrayLevelEmphasis" 31.000000 ################
#     2.                         "90Percentile" 26.000000 #############
#     3.            "HighGrayLevelZoneEmphasis" 23.000000 ###########
#     4.                          "TotalEnergy" 23.000000 ###########
#     5.                "HighGrayLevelEmphasis" 22.000000 ###########
#     6.                      "Autocorrelation" 19.000000 #########
#     7.                               "Energy" 19.000000 #########
#     8.                           "SumAverage" 19.000000 #########
#     9.                         "JointAverage" 16.000000 ########
#    10.                      "RootMeanSquared" 15.000000 #######
#    11.                                 "Mean" 14.000000 ######
#    12.        "ShortRunHighGrayLevelEmphasis" 10.000000 ####
#    13.       "SmallAreaHighGrayLevelEmphasis" 10.000000 ####
#    14.                              "Maximum"  8.000000 ###
#    15.                               "Median"  6.000000 ##
#    16.             "HighGrayLevelRunEmphasis"  5.000000 ##
#    17.                             "Busyness"  4.000000 #
#    18. "SmallDependenceHighGrayLevelEmphasis"  4.000000 #
#    19.                              "Minimum"  3.000000 #
#    20.         "ShortRunLowGrayLevelEmphasis"  3.000000 #
#    21.                           "Coarseness"  2.000000
#    22.                 "LowGrayLevelEmphasis"  2.000000
#    23.              "LowGrayLevelRunEmphasis"  2.000000
#    24.             "LowGrayLevelZoneEmphasis"  2.000000
#    25.        "SmallAreaLowGrayLevelEmphasis"  2.000000
#    26.                           "Uniformity"  2.000000
#    27.                         "10Percentile"  1.000000
#    28.                    "DependenceEntropy"  1.000000
#    29.               "GrayLevelNonUniformity"  1.000000
#    30.                                 "Imc1"  1.000000
#    31. "LargeDependenceHighGrayLevelEmphasis"  1.000000
#    32.  "LargeDependenceLowGrayLevelEmphasis"  1.000000
#    33.                                  "MCC"  1.000000
#    34.  "SmallDependenceLowGrayLevelEmphasis"  1.000000
#
# Variable Importance: NUM_NODES:
#     1.                                  "Idn" 967.000000 ################
#     2.                                 "Idmn" 805.000000 ############
#     3. "LargeDependenceHighGrayLevelEmphasis" 696.000000 ##########
#     4.                             "Skewness" 648.000000 #########
#     5.                             "Busyness" 622.000000 #########
#     6.                         "ClusterShade" 602.000000 ########
#     7.             "GrayLevelNonUniformity.2" 579.000000 ########
#     8.                              "Maximum" 559.000000 #######
#     9.                               "Median" 559.000000 #######
#    10.         "LongRunHighGrayLevelEmphasis" 548.000000 #######
#    11.                           "Coarseness" 537.000000 #######
#    12.                                 "Imc1" 449.000000 #####
#    13.                    "DependenceEntropy" 439.000000 #####
#    14.                         "90Percentile" 404.000000 ####
#    15.                                 "Imc2" 402.000000 ####
#    16.                             "Kurtosis" 390.000000 ####
#    17.                           "Contrast.1" 377.000000 ####
#    18.                          "Correlation" 375.000000 ####
#    19.       "LargeAreaHighGrayLevelEmphasis" 367.000000 ####
#    20.       "SmallAreaHighGrayLevelEmphasis" 366.000000 ####
#    21.                           "SumAverage" 365.000000 ####
#    22.                         "JointAverage" 363.000000 ###
#    23.                      "Autocorrelation" 357.000000 ###
#    24.                                 "Mean" 344.000000 ###
#    25.            "HighGrayLevelZoneEmphasis" 336.000000 ###
#    26.                             "Strength" 326.000000 ###
#    27.                "HighGrayLevelEmphasis" 325.000000 ###
#    28. "SmallDependenceHighGrayLevelEmphasis" 324.000000 ###
#    29.                   "DifferenceVariance" 323.000000 ###
#    30.                                  "MCC" 320.000000 ###
#    31.                                "Range" 320.000000 ###
#    32.                          "TotalEnergy" 312.000000 ##
#    33.                          "ZoneEntropy" 295.000000 ##
#    34.  "SmallDependenceLowGrayLevelEmphasis" 291.000000 ##
#    35.                             "Contrast" 290.000000 ##
#    36.  "LargeDependenceLowGrayLevelEmphasis" 290.000000 ##
#    37.        "LargeAreaLowGrayLevelEmphasis" 288.000000 ##
#    38.                              "Minimum" 285.000000 ##
#    39.                 "LowGrayLevelEmphasis" 283.000000 ##
#    40.                      "RootMeanSquared" 282.000000 ##
#    41.                           "SumEntropy" 282.000000 ##
#    42.   "GrayLevelNonUniformityNormalized.1" 276.000000 ##
#    43.          "LongRunLowGrayLevelEmphasis" 276.000000 ##
#    44.             "HighGrayLevelRunEmphasis" 275.000000 ##
#    45.         "ShortRunLowGrayLevelEmphasis" 274.000000 ##
#    46.        "SmallAreaLowGrayLevelEmphasis" 274.000000 ##
#    47.        "ShortRunHighGrayLevelEmphasis" 273.000000 ##
#    48.                               "Energy" 263.000000 #
#    49.             "LowGrayLevelZoneEmphasis" 263.000000 #
#    50.                           "RunEntropy" 262.000000 #
#    51.                           "Uniformity" 258.000000 #
#    52.    "DependenceNonUniformityNormalized" 256.000000 #
#    53.               "GrayLevelNonUniformity" 256.000000 #
#    54.                           "Complexity" 255.000000 #
#    55.              "LowGrayLevelRunEmphasis" 254.000000 #
#    56.              "SmallDependenceEmphasis" 254.000000 #
#    57.              "DependenceNonUniformity" 251.000000 #
#    58.                   "MaximumProbability" 251.000000 #
#    59.     "GrayLevelNonUniformityNormalized" 246.000000 #
#    60.                  "GrayLevelVariance.2" 245.000000 #
#    61.             "GrayLevelNonUniformity.1" 244.000000 #
#    62.                "SizeZoneNonUniformity" 241.000000 #
#    63.                      "InverseVariance" 240.000000 #
#    64.                         "10Percentile" 234.000000 #
#    65.                   "DependenceVariance" 233.000000 #
#    66.                              "Entropy" 231.000000 #
#    67.                   "InterquartileRange" 229.000000 #
#    68.                          "RunVariance" 226.000000 #
#    69.      "SizeZoneNonUniformityNormalized" 226.000000 #
#    70.                    "ClusterProminence" 221.000000 #
#    71.                    "DifferenceAverage" 221.000000 #
#    72.                    "SmallAreaEmphasis" 219.000000 #
#    73.                          "JointEnergy" 212.000000
#    74.     "RunLengthNonUniformityNormalized" 209.000000
#    75.                    "DifferenceEntropy" 207.000000
#    76.                                   "Id" 207.000000
#    77.                       "ZonePercentage" 207.000000
#    78.              "LargeDependenceEmphasis" 199.000000
#    79.                                  "Idm" 195.000000
#    80.                    "LargeAreaEmphasis" 192.000000
#    81.               "RunLengthNonUniformity" 189.000000
#    82.                        "RunPercentage" 189.000000
#    83.                           "SumSquares" 188.000000
#    84.                      "LongRunEmphasis" 187.000000
#    85.                  "GrayLevelVariance.1" 182.000000
#    86.                         "JointEntropy" 181.000000
#    87.                             "Variance" 181.000000
#    88.                         "ZoneVariance" 181.000000
#    89.          "RobustMeanAbsoluteDeviation" 177.000000
#    90.                    "GrayLevelVariance" 173.000000
#    91.                "MeanAbsoluteDeviation" 173.000000
#    92.                      "ClusterTendency" 166.000000
#    93.                     "ShortRunEmphasis" 163.000000
#
# Variable Importance: SUM_SCORE:
#     1.         "LongRunHighGrayLevelEmphasis" 102860.003876 ################
#     2.                         "90Percentile" 70223.476748 ##########
#     3.                          "TotalEnergy" 62539.297130 #########
#     4.                "HighGrayLevelEmphasis" 59704.490719 #########
#     5. "LargeDependenceHighGrayLevelEmphasis" 58007.708167 ########
#     6.            "HighGrayLevelZoneEmphasis" 56681.751099 ########
#     7.                      "Autocorrelation" 56414.116552 ########
#     8.                           "SumAverage" 56355.425365 ########
#     9.                               "Energy" 48640.479799 #######
#    10.                                 "Mean" 46744.603302 #######
#    11.                             "Busyness" 46442.705339 ######
#    12.                         "JointAverage" 46204.826308 ######
#    13.                      "RootMeanSquared" 41292.389494 ######
#    14.             "GrayLevelNonUniformity.2" 36317.954463 #####
#    15.                               "Median" 33947.378325 #####
#    16.                              "Maximum" 33754.437804 ####
#    17.                           "Coarseness" 32830.902142 ####
#    18.       "SmallAreaHighGrayLevelEmphasis" 30082.877405 ####
#    19.        "ShortRunHighGrayLevelEmphasis" 29242.209200 ####
#    20.                                  "Idn" 29190.788442 ####
#    21.                                 "Idmn" 24080.844782 ###
#    22.       "LargeAreaHighGrayLevelEmphasis" 21938.248642 ###
#    23.                    "DependenceEntropy" 21418.858600 ###
#    24.             "HighGrayLevelRunEmphasis" 19621.725755 ##
#    25. "SmallDependenceHighGrayLevelEmphasis" 19244.786556 ##
#    26.                                 "Imc1" 19093.012278 ##
#    27.                             "Skewness" 14768.684488 #
#    28.    "DependenceNonUniformityNormalized" 12874.138097 #
#    29.                                 "Imc2" 12293.715459 #
#    30.                      "InverseVariance" 12011.009414 #
#    31.              "DependenceNonUniformity" 11925.040853 #
#    32.         "ShortRunLowGrayLevelEmphasis" 11740.596288 #
#    33.                         "ClusterShade" 11505.195880 #
#    34.  "SmallDependenceLowGrayLevelEmphasis" 9729.091621 #
#    35.                          "Correlation" 9672.081712 #
#    36.                 "LowGrayLevelEmphasis" 9408.669905 #
#    37.  "LargeDependenceLowGrayLevelEmphasis" 9151.181076 #
#    38.          "LongRunLowGrayLevelEmphasis" 8755.595046
#    39.              "LowGrayLevelRunEmphasis" 8466.610185
#    40.             "LowGrayLevelZoneEmphasis" 8397.958764
#    41.                           "SumEntropy" 8245.856505
#    42.                           "Contrast.1" 8112.079011
#    43.        "SmallAreaLowGrayLevelEmphasis" 7968.249703
#    44.                                  "MCC" 7852.216268
#    45.                              "Minimum" 7786.470835
#    46.                             "Strength" 7695.372350
#    47.                           "Uniformity" 7481.321269
#    48.                         "10Percentile" 7349.224615
#    49.               "GrayLevelNonUniformity" 7201.629370
#    50.              "SmallDependenceEmphasis" 7178.997761
#    51.                          "ZoneEntropy" 7074.658041
#    52.        "LargeAreaLowGrayLevelEmphasis" 6878.948374
#    53.                             "Kurtosis" 6807.661426
#    54.                "SizeZoneNonUniformity" 6784.555583
#    55.                                "Range" 6554.470602
#    56.   "GrayLevelNonUniformityNormalized.1" 6516.750943
#    57.                           "RunEntropy" 6469.434567
#    58.                   "DifferenceVariance" 6260.492540
#    59.                             "Contrast" 6086.900339
#    60.                       "ZonePercentage" 5669.540851
#    61.                              "Entropy" 5467.947255
#    62.                   "DependenceVariance" 5433.799114
#    63.                                  "Idm" 5332.802294
#    64.     "RunLengthNonUniformityNormalized" 5283.503646
#    65.                      "LongRunEmphasis" 5281.050146
#    66.     "GrayLevelNonUniformityNormalized" 5196.394538
#    67.                   "MaximumProbability" 5042.792585
#    68.                           "Complexity" 4935.277806
#    69.             "GrayLevelNonUniformity.1" 4835.347755
#    70.                                   "Id" 4834.015708
#    71.                          "JointEnergy" 4716.147588
#    72.                          "RunVariance" 4600.037904
#    73.                  "GrayLevelVariance.2" 4552.902309
#    74.               "RunLengthNonUniformity" 4508.504629
#    75.      "SizeZoneNonUniformityNormalized" 4239.320152
#    76.                    "LargeAreaEmphasis" 3973.242051
#    77.              "LargeDependenceEmphasis" 3850.606018
#    78.                    "DifferenceAverage" 3837.169804
#    79.                    "ClusterProminence" 3829.024267
#    80.                    "DifferenceEntropy" 3823.726445
#    81.                        "RunPercentage" 3788.906519
#    82.                   "InterquartileRange" 3765.188398
#    83.                     "ShortRunEmphasis" 3686.702463
#    84.                    "SmallAreaEmphasis" 3559.110459
#    85.                         "ZoneVariance" 3345.355028
#    86.                      "ClusterTendency" 3257.437882
#    87.                           "SumSquares" 3239.212267
#    88.                             "Variance" 3179.184911
#    89.                  "GrayLevelVariance.1" 3130.195504
#    90.          "RobustMeanAbsoluteDeviation" 3043.746089
#    91.                         "JointEntropy" 2994.345709
#    92.                    "GrayLevelVariance" 2868.073156
#    93.                "MeanAbsoluteDeviation" 2594.510369
#
#
#
# Winner takes all: true
# Out-of-bag evaluation: accuracy:0.885657 logloss:0.247419
# Number of trees: 300
# Total number of nodes: 58254
#
# Number of nodes by tree:
# Count: 300 Average: 194.18 StdDev: 11.8954
# Min: 157 Max: 231 Ignored: 0
# ----------------------------------------------
# [ 157, 160)  1   0.33%   0.33%
# [ 160, 164)  1   0.33%   0.67%
# [ 164, 168)  1   0.33%   1.00%
# [ 168, 172)  7   2.33%   3.33% #
# [ 172, 175)  7   2.33%   5.67% #
# [ 175, 179) 11   3.67%   9.33% ##
# [ 179, 183) 21   7.00%  16.33% ####
# [ 183, 187) 27   9.00%  25.33% ######
# [ 187, 190) 29   9.67%  35.00% ######
# [ 190, 194) 29   9.67%  44.67% ######
# [ 194, 198) 48  16.00%  60.67% ##########
# [ 198, 202) 43  14.33%  75.00% #########
# [ 202, 205) 17   5.67%  80.67% ####
# [ 205, 209) 29   9.67%  90.33% ######
# [ 209, 213) 11   3.67%  94.00% ##
# [ 213, 217)  6   2.00%  96.00% #
# [ 217, 220) 10   3.33%  99.33% ##
# [ 220, 224)  0   0.00%  99.33%
# [ 224, 228)  1   0.33%  99.67%
# [ 228, 231]  1   0.33% 100.00%
#
# Depth by leafs:
# Count: 29277 Average: 8.4316 StdDev: 2.51756
# Min: 2 Max: 15 Ignored: 0
# ----------------------------------------------
# [  2,  3)   25   0.09%   0.09%
# [  3,  4)  365   1.25%   1.33% #
# [  4,  5) 1093   3.73%   5.07% ##
# [  5,  6) 2092   7.15%  12.21% #####
# [  6,  7) 3257  11.12%  23.34% #######
# [  7,  8) 4154  14.19%  37.52% #########
# [  8,  9) 4515  15.42%  52.95% ##########
# [  9, 10) 4205  14.36%  67.31% #########
# [ 10, 11) 3494  11.93%  79.24% ########
# [ 11, 12) 2601   8.88%  88.13% ######
# [ 12, 13) 1644   5.62%  93.74% ####
# [ 13, 14)  963   3.29%  97.03% ##
# [ 14, 15)  543   1.85%  98.89% #
# [ 15, 15]  326   1.11% 100.00% #
#
# Number of training obs by leaf:
# Count: 29277 Average: 78.051 StdDev: 279.065
# Min: 5 Max: 3915 Ignored: 0
# ----------------------------------------------
# [    5,  200) 27149  92.73%  92.73% ##########
# [  200,  396)   833   2.85%  95.58%
# [  396,  591)   326   1.11%  96.69%
# [  591,  787)   202   0.69%  97.38%
# [  787,  982)   182   0.62%  98.00%
# [  982, 1178)   133   0.45%  98.46%
# [ 1178, 1373)    90   0.31%  98.76%
# [ 1373, 1569)    55   0.19%  98.95%
# [ 1569, 1764)    47   0.16%  99.11%
# [ 1764, 1960)    55   0.19%  99.30%
# [ 1960, 2156)    48   0.16%  99.46%
# [ 2156, 2351)    43   0.15%  99.61%
# [ 2351, 2547)    41   0.14%  99.75%
# [ 2547, 2742)    25   0.09%  99.84%
# [ 2742, 2938)    18   0.06%  99.90%
# [ 2938, 3133)    15   0.05%  99.95%
# [ 3133, 3329)     7   0.02%  99.97%
# [ 3329, 3524)     5   0.02%  99.99%
# [ 3524, 3720)     2   0.01% 100.00%
# [ 3720, 3915]     1   0.00% 100.00%
#
# Attribute in nodes:
# 	967 : Idn [NUMERICAL]
# 	805 : Idmn [NUMERICAL]
# 	696 : LargeDependenceHighGrayLevelEmphasis [NUMERICAL]
# 	648 : Skewness [NUMERICAL]
# 	622 : Busyness [NUMERICAL]
# 	602 : ClusterShade [NUMERICAL]
# 	579 : GrayLevelNonUniformity.2 [NUMERICAL]
# 	559 : Median [NUMERICAL]
# 	559 : Maximum [NUMERICAL]
# 	548 : LongRunHighGrayLevelEmphasis [NUMERICAL]
# 	537 : Coarseness [NUMERICAL]
# 	449 : Imc1 [NUMERICAL]
# 	439 : DependenceEntropy [NUMERICAL]
# 	404 : 90Percentile [NUMERICAL]
# 	402 : Imc2 [NUMERICAL]
# 	390 : Kurtosis [NUMERICAL]
# 	377 : Contrast.1 [NUMERICAL]
# 	375 : Correlation [NUMERICAL]
# 	367 : LargeAreaHighGrayLevelEmphasis [NUMERICAL]
# 	366 : SmallAreaHighGrayLevelEmphasis [NUMERICAL]
# 	365 : SumAverage [NUMERICAL]
# 	363 : JointAverage [NUMERICAL]
# 	357 : Autocorrelation [NUMERICAL]
# 	344 : Mean [NUMERICAL]
# 	336 : HighGrayLevelZoneEmphasis [NUMERICAL]
# 	326 : Strength [NUMERICAL]
# 	325 : HighGrayLevelEmphasis [NUMERICAL]
# 	324 : SmallDependenceHighGrayLevelEmphasis [NUMERICAL]
# 	323 : DifferenceVariance [NUMERICAL]
# 	320 : Range [NUMERICAL]
# 	320 : MCC [NUMERICAL]
# 	312 : TotalEnergy [NUMERICAL]
# 	295 : ZoneEntropy [NUMERICAL]
# 	291 : SmallDependenceLowGrayLevelEmphasis [NUMERICAL]
# 	290 : LargeDependenceLowGrayLevelEmphasis [NUMERICAL]
# 	290 : Contrast [NUMERICAL]
# 	288 : LargeAreaLowGrayLevelEmphasis [NUMERICAL]
# 	285 : Minimum [NUMERICAL]
# 	283 : LowGrayLevelEmphasis [NUMERICAL]
# 	282 : SumEntropy [NUMERICAL]
# 	282 : RootMeanSquared [NUMERICAL]
# 	276 : LongRunLowGrayLevelEmphasis [NUMERICAL]
# 	276 : GrayLevelNonUniformityNormalized.1 [NUMERICAL]
# 	275 : HighGrayLevelRunEmphasis [NUMERICAL]
# 	274 : SmallAreaLowGrayLevelEmphasis [NUMERICAL]
# 	274 : ShortRunLowGrayLevelEmphasis [NUMERICAL]
# 	273 : ShortRunHighGrayLevelEmphasis [NUMERICAL]
# 	263 : LowGrayLevelZoneEmphasis [NUMERICAL]
# 	263 : Energy [NUMERICAL]
# 	262 : RunEntropy [NUMERICAL]
# 	258 : Uniformity [NUMERICAL]
# 	256 : GrayLevelNonUniformity [NUMERICAL]
# 	256 : DependenceNonUniformityNormalized [NUMERICAL]
# 	255 : Complexity [NUMERICAL]
# 	254 : SmallDependenceEmphasis [NUMERICAL]
# 	254 : LowGrayLevelRunEmphasis [NUMERICAL]
# 	251 : MaximumProbability [NUMERICAL]
# 	251 : DependenceNonUniformity [NUMERICAL]
# 	246 : GrayLevelNonUniformityNormalized [NUMERICAL]
# 	245 : GrayLevelVariance.2 [NUMERICAL]
# 	244 : GrayLevelNonUniformity.1 [NUMERICAL]
# 	241 : SizeZoneNonUniformity [NUMERICAL]
# 	240 : InverseVariance [NUMERICAL]
# 	234 : 10Percentile [NUMERICAL]
# 	233 : DependenceVariance [NUMERICAL]
# 	231 : Entropy [NUMERICAL]
# 	229 : InterquartileRange [NUMERICAL]
# 	226 : SizeZoneNonUniformityNormalized [NUMERICAL]
# 	226 : RunVariance [NUMERICAL]
# 	221 : DifferenceAverage [NUMERICAL]
# 	221 : ClusterProminence [NUMERICAL]
# 	219 : SmallAreaEmphasis [NUMERICAL]
# 	212 : JointEnergy [NUMERICAL]
# 	209 : RunLengthNonUniformityNormalized [NUMERICAL]
# 	207 : ZonePercentage [NUMERICAL]
# 	207 : Id [NUMERICAL]
# 	207 : DifferenceEntropy [NUMERICAL]
# 	199 : LargeDependenceEmphasis [NUMERICAL]
# 	195 : Idm [NUMERICAL]
# 	192 : LargeAreaEmphasis [NUMERICAL]
# 	189 : RunPercentage [NUMERICAL]
# 	189 : RunLengthNonUniformity [NUMERICAL]
# 	188 : SumSquares [NUMERICAL]
# 	187 : LongRunEmphasis [NUMERICAL]
# 	182 : GrayLevelVariance.1 [NUMERICAL]
# 	181 : ZoneVariance [NUMERICAL]
# 	181 : Variance [NUMERICAL]
# 	181 : JointEntropy [NUMERICAL]
# 	177 : RobustMeanAbsoluteDeviation [NUMERICAL]
# 	173 : MeanAbsoluteDeviation [NUMERICAL]
# 	173 : GrayLevelVariance [NUMERICAL]
# 	166 : ClusterTendency [NUMERICAL]
# 	163 : ShortRunEmphasis [NUMERICAL]
#
# Attribute in nodes with depth <= 0:
# 	31 : LongRunHighGrayLevelEmphasis [NUMERICAL]
# 	26 : 90Percentile [NUMERICAL]
# 	23 : TotalEnergy [NUMERICAL]
# 	23 : HighGrayLevelZoneEmphasis [NUMERICAL]
# 	22 : HighGrayLevelEmphasis [NUMERICAL]
# 	19 : SumAverage [NUMERICAL]
# 	19 : Energy [NUMERICAL]
# 	19 : Autocorrelation [NUMERICAL]
# 	16 : JointAverage [NUMERICAL]
# 	15 : RootMeanSquared [NUMERICAL]
# 	14 : Mean [NUMERICAL]
# 	10 : SmallAreaHighGrayLevelEmphasis [NUMERICAL]
# 	10 : ShortRunHighGrayLevelEmphasis [NUMERICAL]
# 	8 : Maximum [NUMERICAL]
# 	6 : Median [NUMERICAL]
# 	5 : HighGrayLevelRunEmphasis [NUMERICAL]
# 	4 : SmallDependenceHighGrayLevelEmphasis [NUMERICAL]
# 	4 : Busyness [NUMERICAL]
# 	3 : ShortRunLowGrayLevelEmphasis [NUMERICAL]
# 	3 : Minimum [NUMERICAL]
# 	2 : Uniformity [NUMERICAL]
# 	2 : SmallAreaLowGrayLevelEmphasis [NUMERICAL]
# 	2 : LowGrayLevelZoneEmphasis [NUMERICAL]
# 	2 : LowGrayLevelRunEmphasis [NUMERICAL]
# 	2 : LowGrayLevelEmphasis [NUMERICAL]
# 	2 : Coarseness [NUMERICAL]
# 	1 : SmallDependenceLowGrayLevelEmphasis [NUMERICAL]
# 	1 : MCC [NUMERICAL]
# 	1 : LargeDependenceLowGrayLevelEmphasis [NUMERICAL]
# 	1 : LargeDependenceHighGrayLevelEmphasis [NUMERICAL]
# 	1 : Imc1 [NUMERICAL]
# 	1 : GrayLevelNonUniformity [NUMERICAL]
# 	1 : DependenceEntropy [NUMERICAL]
# 	1 : 10Percentile [NUMERICAL]
#
# Attribute in nodes with depth <= 1:
# 	89 : LongRunHighGrayLevelEmphasis [NUMERICAL]
# 	56 : SumAverage [NUMERICAL]
# 	54 : Autocorrelation [NUMERICAL]
# 	47 : Mean [NUMERICAL]
# 	44 : LargeDependenceHighGrayLevelEmphasis [NUMERICAL]
# 	43 : HighGrayLevelEmphasis [NUMERICAL]
# 	42 : Median [NUMERICAL]
# 	42 : JointAverage [NUMERICAL]
# 	41 : TotalEnergy [NUMERICAL]
# 	34 : 90Percentile [NUMERICAL]
# 	31 : Energy [NUMERICAL]
# 	30 : Coarseness [NUMERICAL]
# 	28 : HighGrayLevelZoneEmphasis [NUMERICAL]
# 	27 : ShortRunHighGrayLevelEmphasis [NUMERICAL]
# 	26 : Busyness [NUMERICAL]
# 	25 : RootMeanSquared [NUMERICAL]
# 	23 : GrayLevelNonUniformity.2 [NUMERICAL]
# 	21 : LargeAreaHighGrayLevelEmphasis [NUMERICAL]
# 	20 : HighGrayLevelRunEmphasis [NUMERICAL]
# 	19 : SmallAreaHighGrayLevelEmphasis [NUMERICAL]
# 	16 : Maximum [NUMERICAL]
# 	13 : ShortRunLowGrayLevelEmphasis [NUMERICAL]
# 	13 : InverseVariance [NUMERICAL]
# 	12 : LowGrayLevelEmphasis [NUMERICAL]
# 	10 : Imc1 [NUMERICAL]
# 	9 : SmallAreaLowGrayLevelEmphasis [NUMERICAL]
# 	9 : DependenceNonUniformityNormalized [NUMERICAL]
# 	8 : SmallDependenceLowGrayLevelEmphasis [NUMERICAL]
# 	6 : LowGrayLevelRunEmphasis [NUMERICAL]
# 	5 : SmallDependenceHighGrayLevelEmphasis [NUMERICAL]
# 	5 : DependenceNonUniformity [NUMERICAL]
# 	5 : 10Percentile [NUMERICAL]
# 	4 : Minimum [NUMERICAL]
# 	4 : MCC [NUMERICAL]
# 	4 : DependenceEntropy [NUMERICAL]
# 	4 : Correlation [NUMERICAL]
# 	3 : SmallDependenceEmphasis [NUMERICAL]
# 	3 : SizeZoneNonUniformity [NUMERICAL]
# 	3 : ShortRunEmphasis [NUMERICAL]
# 	3 : LowGrayLevelZoneEmphasis [NUMERICAL]
# 	3 : LongRunLowGrayLevelEmphasis [NUMERICAL]
# 	3 : Contrast.1 [NUMERICAL]
# 	2 : Uniformity [NUMERICAL]
# 	2 : RunLengthNonUniformityNormalized [NUMERICAL]
# 	2 : LargeDependenceLowGrayLevelEmphasis [NUMERICAL]
# 	1 : ZonePercentage [NUMERICAL]
# 	1 : Strength [NUMERICAL]
# 	1 : LargeDependenceEmphasis [NUMERICAL]
# 	1 : LargeAreaLowGrayLevelEmphasis [NUMERICAL]
# 	1 : Idm [NUMERICAL]
# 	1 : Id [NUMERICAL]
# 	1 : GrayLevelNonUniformity [NUMERICAL]
#
# Attribute in nodes with depth <= 2:
# 	123 : LongRunHighGrayLevelEmphasis [NUMERICAL]
# 	100 : LargeDependenceHighGrayLevelEmphasis [NUMERICAL]
# 	94 : SumAverage [NUMERICAL]
# 	89 : Autocorrelation [NUMERICAL]
# 	80 : Median [NUMERICAL]
# 	73 : Coarseness [NUMERICAL]
# 	70 : JointAverage [NUMERICAL]
# 	69 : HighGrayLevelEmphasis [NUMERICAL]
# 	68 : GrayLevelNonUniformity.2 [NUMERICAL]
# 	67 : Mean [NUMERICAL]
# 	65 : Busyness [NUMERICAL]
# 	58 : Skewness [NUMERICAL]
# 	57 : 90Percentile [NUMERICAL]
# 	56 : TotalEnergy [NUMERICAL]
# 	51 : Energy [NUMERICAL]
# 	49 : Imc1 [NUMERICAL]
# 	40 : RootMeanSquared [NUMERICAL]
# 	39 : LargeAreaHighGrayLevelEmphasis [NUMERICAL]
# 	37 : DependenceEntropy [NUMERICAL]
# 	35 : ShortRunHighGrayLevelEmphasis [NUMERICAL]
# 	35 : HighGrayLevelRunEmphasis [NUMERICAL]
# 	34 : HighGrayLevelZoneEmphasis [NUMERICAL]
# 	34 : ClusterShade [NUMERICAL]
# 	30 : DependenceNonUniformityNormalized [NUMERICAL]
# 	29 : Maximum [NUMERICAL]
# 	26 : LowGrayLevelEmphasis [NUMERICAL]
# 	26 : DependenceNonUniformity [NUMERICAL]
# 	25 : ShortRunLowGrayLevelEmphasis [NUMERICAL]
# 	24 : InverseVariance [NUMERICAL]
# 	23 : Correlation [NUMERICAL]
# 	22 : SmallDependenceHighGrayLevelEmphasis [NUMERICAL]
# 	22 : SmallAreaHighGrayLevelEmphasis [NUMERICAL]
# 	20 : SmallDependenceLowGrayLevelEmphasis [NUMERICAL]
# 	20 : LongRunLowGrayLevelEmphasis [NUMERICAL]
# 	18 : LowGrayLevelRunEmphasis [NUMERICAL]
# 	17 : Imc2 [NUMERICAL]
# 	14 : SmallDependenceEmphasis [NUMERICAL]
# 	13 : SmallAreaLowGrayLevelEmphasis [NUMERICAL]
# 	13 : MCC [NUMERICAL]
# 	13 : 10Percentile [NUMERICAL]
# 	12 : LowGrayLevelZoneEmphasis [NUMERICAL]
# 	11 : SumEntropy [NUMERICAL]
# 	11 : LargeDependenceLowGrayLevelEmphasis [NUMERICAL]
# 	10 : LongRunEmphasis [NUMERICAL]
# 	10 : DifferenceVariance [NUMERICAL]
# 	9 : Strength [NUMERICAL]
# 	9 : SizeZoneNonUniformity [NUMERICAL]
# 	9 : RunVariance [NUMERICAL]
# 	9 : Idn [NUMERICAL]
# 	8 : Uniformity [NUMERICAL]
# 	8 : RunLengthNonUniformityNormalized [NUMERICAL]
# 	8 : Id [NUMERICAL]
# 	8 : GrayLevelNonUniformity [NUMERICAL]
# 	8 : DifferenceAverage [NUMERICAL]
# 	7 : MaximumProbability [NUMERICAL]
# 	7 : LargeAreaLowGrayLevelEmphasis [NUMERICAL]
# 	7 : Idmn [NUMERICAL]
# 	7 : Idm [NUMERICAL]
# 	7 : GrayLevelVariance [NUMERICAL]
# 	7 : Contrast [NUMERICAL]
# 	6 : ZonePercentage [NUMERICAL]
# 	6 : SizeZoneNonUniformityNormalized [NUMERICAL]
# 	6 : RunPercentage [NUMERICAL]
# 	6 : RunLengthNonUniformity [NUMERICAL]
# 	6 : Range [NUMERICAL]
# 	6 : JointEnergy [NUMERICAL]
# 	6 : GrayLevelNonUniformityNormalized.1 [NUMERICAL]
# 	6 : Entropy [NUMERICAL]
# 	5 : Variance [NUMERICAL]
# 	5 : ShortRunEmphasis [NUMERICAL]
# 	5 : Minimum [NUMERICAL]
# 	5 : GrayLevelVariance.2 [NUMERICAL]
# 	5 : Contrast.1 [NUMERICAL]
# 	4 : ZoneEntropy [NUMERICAL]
# 	4 : SumSquares [NUMERICAL]
# 	4 : RunEntropy [NUMERICAL]
# 	4 : LargeDependenceEmphasis [NUMERICAL]
# 	4 : GrayLevelNonUniformityNormalized [NUMERICAL]
# 	4 : GrayLevelNonUniformity.1 [NUMERICAL]
# 	4 : DifferenceEntropy [NUMERICAL]
# 	4 : DependenceVariance [NUMERICAL]
# 	4 : ClusterProminence [NUMERICAL]
# 	3 : ZoneVariance [NUMERICAL]
# 	3 : RobustMeanAbsoluteDeviation [NUMERICAL]
# 	2 : LargeAreaEmphasis [NUMERICAL]
# 	2 : Kurtosis [NUMERICAL]
# 	2 : GrayLevelVariance.1 [NUMERICAL]
# 	1 : SmallAreaEmphasis [NUMERICAL]
# 	1 : MeanAbsoluteDeviation [NUMERICAL]
# 	1 : InterquartileRange [NUMERICAL]
# 	1 : ClusterTendency [NUMERICAL]
#
# Attribute in nodes with depth <= 3:
# 	177 : LargeDependenceHighGrayLevelEmphasis [NUMERICAL]
# 	168 : LongRunHighGrayLevelEmphasis [NUMERICAL]
# 	137 : GrayLevelNonUniformity.2 [NUMERICAL]
# 	135 : Busyness [NUMERICAL]
# 	132 : Coarseness [NUMERICAL]
# 	131 : Median [NUMERICAL]
# 	123 : Skewness [NUMERICAL]
# 	120 : SumAverage [NUMERICAL]
# 	117 : Autocorrelation [NUMERICAL]
# 	110 : JointAverage [NUMERICAL]
# 	102 : Mean [NUMERICAL]
# 	94 : Imc1 [NUMERICAL]
# 	91 : 90Percentile [NUMERICAL]
# 	89 : DependenceEntropy [NUMERICAL]
# 	88 : HighGrayLevelEmphasis [NUMERICAL]
# 	81 : TotalEnergy [NUMERICAL]
# 	81 : Maximum [NUMERICAL]
# 	78 : ClusterShade [NUMERICAL]
# 	68 : Energy [NUMERICAL]
# 	63 : LargeAreaHighGrayLevelEmphasis [NUMERICAL]
# 	57 : RootMeanSquared [NUMERICAL]
# 	56 : SmallAreaHighGrayLevelEmphasis [NUMERICAL]
# 	55 : DependenceNonUniformityNormalized [NUMERICAL]
# 	54 : HighGrayLevelRunEmphasis [NUMERICAL]
# 	53 : ShortRunHighGrayLevelEmphasis [NUMERICAL]
# 	52 : LowGrayLevelEmphasis [NUMERICAL]
# 	52 : Imc2 [NUMERICAL]
# 	52 : HighGrayLevelZoneEmphasis [NUMERICAL]
# 	49 : ShortRunLowGrayLevelEmphasis [NUMERICAL]
# 	49 : Correlation [NUMERICAL]
# 	47 : Idn [NUMERICAL]
# 	44 : SmallDependenceHighGrayLevelEmphasis [NUMERICAL]
# 	42 : DependenceNonUniformity [NUMERICAL]
# 	41 : LongRunLowGrayLevelEmphasis [NUMERICAL]
# 	39 : SmallDependenceLowGrayLevelEmphasis [NUMERICAL]
# 	37 : InverseVariance [NUMERICAL]
# 	36 : Idmn [NUMERICAL]
# 	34 : MCC [NUMERICAL]
# 	33 : LowGrayLevelRunEmphasis [NUMERICAL]
# 	31 : LargeDependenceLowGrayLevelEmphasis [NUMERICAL]
# 	30 : Kurtosis [NUMERICAL]
# 	28 : Uniformity [NUMERICAL]
# 	28 : LowGrayLevelZoneEmphasis [NUMERICAL]
# 	28 : DifferenceVariance [NUMERICAL]
# 	28 : 10Percentile [NUMERICAL]
# 	26 : SumEntropy [NUMERICAL]
# 	26 : SmallDependenceEmphasis [NUMERICAL]
# 	26 : LongRunEmphasis [NUMERICAL]
# 	26 : GrayLevelNonUniformityNormalized.1 [NUMERICAL]
# 	25 : GrayLevelNonUniformity [NUMERICAL]
# 	25 : Entropy [NUMERICAL]
# 	24 : SizeZoneNonUniformity [NUMERICAL]
# 	24 : RunVariance [NUMERICAL]
# 	24 : Contrast [NUMERICAL]
# 	23 : SmallAreaLowGrayLevelEmphasis [NUMERICAL]
# 	22 : ZoneEntropy [NUMERICAL]
# 	22 : Strength [NUMERICAL]
# 	22 : Complexity [NUMERICAL]
# 	21 : MaximumProbability [NUMERICAL]
# 	20 : Range [NUMERICAL]
# 	20 : LargeAreaLowGrayLevelEmphasis [NUMERICAL]
# 	20 : GrayLevelVariance.2 [NUMERICAL]
# 	19 : RunEntropy [NUMERICAL]
# 	19 : JointEnergy [NUMERICAL]
# 	19 : Contrast.1 [NUMERICAL]
# 	17 : RunLengthNonUniformityNormalized [NUMERICAL]
# 	17 : Minimum [NUMERICAL]
# 	17 : GrayLevelNonUniformity.1 [NUMERICAL]
# 	16 : ZonePercentage [NUMERICAL]
# 	16 : LargeDependenceEmphasis [NUMERICAL]
# 	16 : Idm [NUMERICAL]
# 	16 : GrayLevelVariance.1 [NUMERICAL]
# 	15 : RunLengthNonUniformity [NUMERICAL]
# 	15 : Id [NUMERICAL]
# 	15 : DependenceVariance [NUMERICAL]
# 	15 : ClusterProminence [NUMERICAL]
# 	14 : RunPercentage [NUMERICAL]
# 	14 : RobustMeanAbsoluteDeviation [NUMERICAL]
# 	14 : GrayLevelNonUniformityNormalized [NUMERICAL]
# 	13 : Variance [NUMERICAL]
# 	13 : SizeZoneNonUniformityNormalized [NUMERICAL]
# 	13 : ShortRunEmphasis [NUMERICAL]
# 	13 : InterquartileRange [NUMERICAL]
# 	13 : DifferenceEntropy [NUMERICAL]
# 	13 : ClusterTendency [NUMERICAL]
# 	12 : LargeAreaEmphasis [NUMERICAL]
# 	11 : DifferenceAverage [NUMERICAL]
# 	10 : ZoneVariance [NUMERICAL]
# 	10 : SumSquares [NUMERICAL]
# 	9 : GrayLevelVariance [NUMERICAL]
# 	7 : SmallAreaEmphasis [NUMERICAL]
# 	7 : JointEntropy [NUMERICAL]
# 	6 : MeanAbsoluteDeviation [NUMERICAL]
#
# Attribute in nodes with depth <= 5:
# 	326 : LargeDependenceHighGrayLevelEmphasis [NUMERICAL]
# 	315 : Busyness [NUMERICAL]
# 	293 : Skewness [NUMERICAL]
# 	281 : LongRunHighGrayLevelEmphasis [NUMERICAL]
# 	278 : GrayLevelNonUniformity.2 [NUMERICAL]
# 	274 : Coarseness [NUMERICAL]
# 	266 : Idn [NUMERICAL]
# 	254 : Median [NUMERICAL]
# 	237 : Maximum [NUMERICAL]
# 	233 : ClusterShade [NUMERICAL]
# 	223 : Idmn [NUMERICAL]
# 	212 : DependenceEntropy [NUMERICAL]
# 	198 : Imc1 [NUMERICAL]
# 	191 : 90Percentile [NUMERICAL]
# 	188 : JointAverage [NUMERICAL]
# 	181 : Autocorrelation [NUMERICAL]
# 	180 : SumAverage [NUMERICAL]
# 	173 : Mean [NUMERICAL]
# 	162 : HighGrayLevelEmphasis [NUMERICAL]
# 	147 : Imc2 [NUMERICAL]
# 	145 : LargeAreaHighGrayLevelEmphasis [NUMERICAL]
# 	142 : SmallDependenceHighGrayLevelEmphasis [NUMERICAL]
# 	140 : Correlation [NUMERICAL]
# 	134 : TotalEnergy [NUMERICAL]
# 	133 : SmallAreaHighGrayLevelEmphasis [NUMERICAL]
# 	129 : HighGrayLevelZoneEmphasis [NUMERICAL]
# 	127 : Energy [NUMERICAL]
# 	122 : RootMeanSquared [NUMERICAL]
# 	115 : LowGrayLevelEmphasis [NUMERICAL]
# 	113 : Kurtosis [NUMERICAL]
# 	109 : GrayLevelNonUniformity [NUMERICAL]
# 	107 : SmallDependenceLowGrayLevelEmphasis [NUMERICAL]
# 	105 : ShortRunLowGrayLevelEmphasis [NUMERICAL]
# 	104 : ShortRunHighGrayLevelEmphasis [NUMERICAL]
# 	104 : HighGrayLevelRunEmphasis [NUMERICAL]
# 	103 : LargeDependenceLowGrayLevelEmphasis [NUMERICAL]
# 	103 : DependenceNonUniformityNormalized [NUMERICAL]
# 	102 : SumEntropy [NUMERICAL]
# 	102 : Range [NUMERICAL]
# 	102 : InverseVariance [NUMERICAL]
# 	102 : DependenceNonUniformity [NUMERICAL]
# 	100 : LongRunLowGrayLevelEmphasis [NUMERICAL]
# 	98 : LowGrayLevelZoneEmphasis [NUMERICAL]
# 	97 : ZoneEntropy [NUMERICAL]
# 	97 : Contrast.1 [NUMERICAL]
# 	95 : DifferenceVariance [NUMERICAL]
# 	94 : Strength [NUMERICAL]
# 	93 : Uniformity [NUMERICAL]
# 	93 : Complexity [NUMERICAL]
# 	92 : MCC [NUMERICAL]
# 	92 : GrayLevelNonUniformityNormalized.1 [NUMERICAL]
# 	88 : LowGrayLevelRunEmphasis [NUMERICAL]
# 	83 : Minimum [NUMERICAL]
# 	81 : Contrast [NUMERICAL]
# 	78 : SmallAreaLowGrayLevelEmphasis [NUMERICAL]
# 	77 : LargeAreaLowGrayLevelEmphasis [NUMERICAL]
# 	75 : SizeZoneNonUniformity [NUMERICAL]
# 	75 : GrayLevelNonUniformityNormalized [NUMERICAL]
# 	74 : MaximumProbability [NUMERICAL]
# 	73 : SmallDependenceEmphasis [NUMERICAL]
# 	73 : DependenceVariance [NUMERICAL]
# 	71 : RunVariance [NUMERICAL]
# 	71 : RunEntropy [NUMERICAL]
# 	71 : Entropy [NUMERICAL]
# 	70 : LongRunEmphasis [NUMERICAL]
# 	69 : 10Percentile [NUMERICAL]
# 	68 : JointEnergy [NUMERICAL]
# 	68 : InterquartileRange [NUMERICAL]
# 	66 : ZonePercentage [NUMERICAL]
# 	65 : SizeZoneNonUniformityNormalized [NUMERICAL]
# 	65 : RunLengthNonUniformityNormalized [NUMERICAL]
# 	63 : ClusterProminence [NUMERICAL]
# 	61 : GrayLevelNonUniformity.1 [NUMERICAL]
# 	60 : GrayLevelVariance.2 [NUMERICAL]
# 	59 : LargeDependenceEmphasis [NUMERICAL]
# 	57 : RunLengthNonUniformity [NUMERICAL]
# 	57 : GrayLevelVariance.1 [NUMERICAL]
# 	55 : DifferenceAverage [NUMERICAL]
# 	54 : RunPercentage [NUMERICAL]
# 	53 : RobustMeanAbsoluteDeviation [NUMERICAL]
# 	53 : Idm [NUMERICAL]
# 	53 : Id [NUMERICAL]
# 	53 : DifferenceEntropy [NUMERICAL]
# 	52 : SmallAreaEmphasis [NUMERICAL]
# 	50 : ZoneVariance [NUMERICAL]
# 	48 : ShortRunEmphasis [NUMERICAL]
# 	48 : ClusterTendency [NUMERICAL]
# 	47 : LargeAreaEmphasis [NUMERICAL]
# 	45 : SumSquares [NUMERICAL]
# 	45 : GrayLevelVariance [NUMERICAL]
# 	41 : Variance [NUMERICAL]
# 	39 : MeanAbsoluteDeviation [NUMERICAL]
# 	39 : JointEntropy [NUMERICAL]
#
# Condition type in nodes:
# 	28977 : HigherCondition
# Condition type in nodes with depth <= 0:
# 	300 : HigherCondition
# Condition type in nodes with depth <= 1:
# 	900 : HigherCondition
# Condition type in nodes with depth <= 2:
# 	2075 : HigherCondition
# Condition type in nodes with depth <= 3:
# 	4060 : HigherCondition
# Condition type in nodes with depth <= 5:
# 	10599 : HigherCondition
# Node format: NOT_SET
#
# Training OOB:
# 	trees: 1, Out-of-bag evaluation: accuracy:0.837954 logloss:5.84073
# 	trees: 11, Out-of-bag evaluation: accuracy:0.861809 logloss:1.82644
# 	trees: 21, Out-of-bag evaluation: accuracy:0.868278 logloss:0.91383
# 	trees: 31, Out-of-bag evaluation: accuracy:0.86993 logloss:0.672642
# 	trees: 41, Out-of-bag evaluation: accuracy:0.871511 logloss:0.604155
# 	trees: 51, Out-of-bag evaluation: accuracy:0.877423 logloss:0.394113
# 	trees: 61, Out-of-bag evaluation: accuracy:0.882666 logloss:0.386309
# 	trees: 71, Out-of-bag evaluation: accuracy:0.887557 logloss:0.379322
# 	trees: 81, Out-of-bag evaluation: accuracy:0.885587 logloss:0.376601
# 	trees: 91, Out-of-bag evaluation: accuracy:0.883756 logloss:0.343641
# 	trees: 101, Out-of-bag evaluation: accuracy:0.884777 logloss:0.34365
# 	trees: 111, Out-of-bag evaluation: accuracy:0.885657 logloss:0.343267
# 	trees: 121, Out-of-bag evaluation: accuracy:0.886888 logloss:0.34468
# 	trees: 131, Out-of-bag evaluation: accuracy:0.886677 logloss:0.345147
# 	trees: 141, Out-of-bag evaluation: accuracy:0.887768 logloss:0.344669
# 	trees: 151, Out-of-bag evaluation: accuracy:0.888788 logloss:0.343518
# 	trees: 161, Out-of-bag evaluation: accuracy:0.888928 logloss:0.312484
# 	trees: 171, Out-of-bag evaluation: accuracy:0.888928 logloss:0.313105
# 	trees: 181, Out-of-bag evaluation: accuracy:0.886607 logloss:0.280219
# 	trees: 191, Out-of-bag evaluation: accuracy:0.887698 logloss:0.280201
# 	trees: 201, Out-of-bag evaluation: accuracy:0.885727 logloss:0.280837
# 	trees: 211, Out-of-bag evaluation: accuracy:0.883616 logloss:0.280861
# 	trees: 221, Out-of-bag evaluation: accuracy:0.885376 logloss:0.280291
# 	trees: 231, Out-of-bag evaluation: accuracy:0.886537 logloss:0.279827
# 	trees: 241, Out-of-bag evaluation: accuracy:0.887347 logloss:0.248264
# 	trees: 251, Out-of-bag evaluation: accuracy:0.886607 logloss:0.248352
# 	trees: 261, Out-of-bag evaluation: accuracy:0.887557 logloss:0.248978
# 	trees: 271, Out-of-bag evaluation: accuracy:0.886467 logloss:0.248789
# 	trees: 281, Out-of-bag evaluation: accuracy:0.886467 logloss:0.248692
# 	trees: 291, Out-of-bag evaluation: accuracy:0.886537 logloss:0.247792
# 	trees: 300, Out-of-bag evaluation: accuracy:0.885657 logloss:0.247419

# %%
# Model features
model.make_inspector().features()
# Out:
# ["10Percentile" (1; #0),
#  "90Percentile" (1; #1),
#  "Autocorrelation" (1; #2),
#  "Busyness" (1; #3),
#  "ClusterProminence" (1; #4),
#  "ClusterShade" (1; #5),
#  "ClusterTendency" (1; #6),
#  "Coarseness" (1; #7),
#  "Complexity" (1; #8),
#  "Contrast" (1; #9),
#  "Contrast.1" (1; #10),
#  "Correlation" (1; #11),
#  "DependenceEntropy" (1; #12),
#  "DependenceNonUniformity" (1; #13),
#  "DependenceNonUniformityNormalized" (1; #14),
#  "DependenceVariance" (1; #15),
#  "DifferenceAverage" (1; #16),
#  "DifferenceEntropy" (1; #17),
#  "DifferenceVariance" (1; #18),
#  "Energy" (1; #19),
#  "Entropy" (1; #20),
#  "GrayLevelNonUniformity" (1; #21),
#  "GrayLevelNonUniformity.1" (1; #22),
#  "GrayLevelNonUniformity.2" (1; #23),
#  "GrayLevelNonUniformityNormalized" (1; #24),
#  "GrayLevelNonUniformityNormalized.1" (1; #25),
#  "GrayLevelVariance" (1; #26),
#  "GrayLevelVariance.1" (1; #27),
#  "GrayLevelVariance.2" (1; #28),
#  "HighGrayLevelEmphasis" (1; #29),
#  "HighGrayLevelRunEmphasis" (1; #30),
#  "HighGrayLevelZoneEmphasis" (1; #31),
#  "Id" (1; #32),
#  "Idm" (1; #33),
#  "Idmn" (1; #34),
#  "Idn" (1; #35),
#  "Imc1" (1; #36),
#  "Imc2" (1; #37),
#  "InterquartileRange" (1; #38),
#  "InverseVariance" (1; #39),
#  "JointAverage" (1; #40),
#  "JointEnergy" (1; #41),
#  "JointEntropy" (1; #42),
#  "Kurtosis" (1; #43),
#  "LargeAreaEmphasis" (1; #44),
#  "LargeAreaHighGrayLevelEmphasis" (1; #45),
#  "LargeAreaLowGrayLevelEmphasis" (1; #46),
#  "LargeDependenceEmphasis" (1; #47),
#  "LargeDependenceHighGrayLevelEmphasis" (1; #48),
#  "LargeDependenceLowGrayLevelEmphasis" (1; #49),
#  "LongRunEmphasis" (1; #50),
#  "LongRunHighGrayLevelEmphasis" (1; #51),
#  "LongRunLowGrayLevelEmphasis" (1; #52),
#  "LowGrayLevelEmphasis" (1; #53),
#  "LowGrayLevelRunEmphasis" (1; #54),
#  "LowGrayLevelZoneEmphasis" (1; #55),
#  "MCC" (1; #56),
#  "Maximum" (1; #57),
#  "MaximumProbability" (1; #58),
#  "Mean" (1; #59),
#  "MeanAbsoluteDeviation" (1; #60),
#  "Median" (1; #61),
#  "Minimum" (1; #62),
#  "Range" (1; #63),
#  "RobustMeanAbsoluteDeviation" (1; #64),
#  "RootMeanSquared" (1; #65),
#  "RunEntropy" (1; #66),
#  "RunLengthNonUniformity" (1; #67),
#  "RunLengthNonUniformityNormalized" (1; #68),
#  "RunPercentage" (1; #69),
#  "RunVariance" (1; #70),
#  "ShortRunEmphasis" (1; #71),
#  "ShortRunHighGrayLevelEmphasis" (1; #72),
#  "ShortRunLowGrayLevelEmphasis" (1; #73),
#  "SizeZoneNonUniformity" (1; #74),
#  "SizeZoneNonUniformityNormalized" (1; #75),
#  "Skewness" (1; #76),
#  "SmallAreaEmphasis" (1; #77),
#  "SmallAreaHighGrayLevelEmphasis" (1; #78),
#  "SmallAreaLowGrayLevelEmphasis" (1; #79),
#  "SmallDependenceEmphasis" (1; #80),
#  "SmallDependenceHighGrayLevelEmphasis" (1; #81),
#  "SmallDependenceLowGrayLevelEmphasis" (1; #82),
#  "Strength" (1; #83),
#  "SumAverage" (1; #84),
#  "SumEntropy" (1; #85),
#  "SumSquares" (1; #86),
#  "TotalEnergy" (1; #87),
#  "Uniformity" (1; #88),
#  "Variance" (1; #89),
#  "ZoneEntropy" (1; #90),
#  "ZonePercentage" (1; #91),
#  "ZoneVariance" (1; #92)]

# %%
# Feature importance
model.make_inspector().variable_importances()
# Out:
# {'INV_MEAN_MIN_DEPTH': [("LongRunHighGrayLevelEmphasis" (1; #51),
#    0.13448229267479658),
#   ("LargeDependenceHighGrayLevelEmphasis" (1; #48), 0.1293318180316002),
#   ("Busyness" (1; #3), 0.12648382355613308),
#   ("GrayLevelNonUniformity.2" (1; #23), 0.1233829349455147),
#   ("90Percentile" (1; #1), 0.12198306554262191),
#   ("Coarseness" (1; #7), 0.12196185473800886),
#   ("SumAverage" (1; #84), 0.1209273965580522),
#   ("Median" (1; #61), 0.12076059245785449),
#   ("Autocorrelation" (1; #2), 0.12045917654812309),
#   ("TotalEnergy" (1; #87), 0.11976155790993256),
#   ("HighGrayLevelEmphasis" (1; #29), 0.11894949268794983),
#   ("JointAverage" (1; #40), 0.11870376799412749),
#   ("Mean" (1; #59), 0.11811300007914562),
#   ("HighGrayLevelZoneEmphasis" (1; #31), 0.11782041775995862),
#   ("Energy" (1; #19), 0.11675491428234919),
#   ("Maximum" (1; #57), 0.1163586291462252),
#   ("Imc1" (1; #36), 0.11610348334755316),
#   ("RootMeanSquared" (1; #65), 0.11549353934958105),
#   ("LargeAreaHighGrayLevelEmphasis" (1; #45), 0.11535074521304896),
#   ("Idn" (1; #35), 0.11479690927889086),
#   ("DependenceEntropy" (1; #12), 0.11451546355344419),
#   ("Skewness" (1; #76), 0.11363267527100504),
#   ("SmallAreaHighGrayLevelEmphasis" (1; #78), 0.11334339958759264),
#   ("ShortRunHighGrayLevelEmphasis" (1; #72), 0.11328996783671923),
#   ("Idmn" (1; #34), 0.11279162388912123),
#   ("DependenceNonUniformityNormalized" (1; #14), 0.1127859001312301),
#   ("SmallDependenceHighGrayLevelEmphasis" (1; #81), 0.11218739287817708),
#   ("InverseVariance" (1; #39), 0.11205210797569468),
#   ("HighGrayLevelRunEmphasis" (1; #30), 0.11183708118474005),
#   ("ClusterShade" (1; #5), 0.1117884029781257),
#   ("DependenceNonUniformity" (1; #13), 0.1117169715003457),
#   ("Correlation" (1; #11), 0.1116428939573074),
#   ("Imc2" (1; #37), 0.11162129308881504),
#   ("ShortRunLowGrayLevelEmphasis" (1; #73), 0.11091948825878355),
#   ("LowGrayLevelEmphasis" (1; #53), 0.11050488566871748),
#   ("SmallDependenceLowGrayLevelEmphasis" (1; #82), 0.11039995974464067),
#   ("LongRunLowGrayLevelEmphasis" (1; #52), 0.11038169826547305),
#   ("MCC" (1; #56), 0.11006401713841518),
#   ("LargeDependenceLowGrayLevelEmphasis" (1; #49), 0.10969185156608323),
#   ("SmallDependenceEmphasis" (1; #80), 0.10957823486500587),
#   ("Strength" (1; #83), 0.109477627663981),
#   ("Uniformity" (1; #88), 0.10941345933963877),
#   ("Contrast.1" (1; #10), 0.10939276333847302),
#   ("Kurtosis" (1; #43), 0.10931899010199533),
#   ("LowGrayLevelRunEmphasis" (1; #54), 0.10928970869552516),
#   ("SizeZoneNonUniformity" (1; #74), 0.10927735290638542),
#   ("Minimum" (1; #62), 0.1092673590044572),
#   ("SumEntropy" (1; #85), 0.10918290345192165),
#   ("Range" (1; #63), 0.10895044977944614),
#   ("GrayLevelNonUniformity" (1; #21), 0.10892866318374718),
#   ("LowGrayLevelZoneEmphasis" (1; #55), 0.10880520725413916),
#   ("RunLengthNonUniformityNormalized" (1; #68), 0.10875235869759174),
#   ("SmallAreaLowGrayLevelEmphasis" (1; #79), 0.10874538764416061),
#   ("LargeAreaLowGrayLevelEmphasis" (1; #46), 0.10873497362245639),
#   ("10Percentile" (1; #0), 0.10869579627086702),
#   ("GrayLevelNonUniformityNormalized.1" (1; #25), 0.10865815501757946),
#   ("Contrast" (1; #9), 0.10865707098746334),
#   ("ZoneEntropy" (1; #90), 0.10860184008920662),
#   ("DifferenceVariance" (1; #18), 0.10853070641489548),
#   ("ZonePercentage" (1; #91), 0.10845829924464095),
#   ("LongRunEmphasis" (1; #50), 0.1084164534895225),
#   ("DependenceVariance" (1; #15), 0.10837360306102513),
#   ("RunVariance" (1; #70), 0.1083583868839065),
#   ("RunLengthNonUniformity" (1; #67), 0.10823962064565316),
#   ("RunEntropy" (1; #66), 0.10823020077424234),
#   ("Complexity" (1; #8), 0.1081984345677551),
#   ("Idm" (1; #33), 0.1081858017029151),
#   ("Id" (1; #32), 0.10813407656567578),
#   ("Entropy" (1; #20), 0.10804943537245681),
#   ("GrayLevelVariance.2" (1; #28), 0.10799723152847117),
#   ("GrayLevelNonUniformity.1" (1; #22), 0.10797670561051395),
#   ("JointEnergy" (1; #41), 0.10796239803591269),
#   ("GrayLevelNonUniformityNormalized" (1; #24), 0.10795120020403094),
#   ("LargeDependenceEmphasis" (1; #47), 0.10785704402930223),
#   ("MaximumProbability" (1; #58), 0.10784092251010609),
#   ("ClusterProminence" (1; #4), 0.10774759953430911),
#   ("SizeZoneNonUniformityNormalized" (1; #75), 0.1077324202747524),
#   ("DifferenceAverage" (1; #16), 0.10766624256795014),
#   ("ShortRunEmphasis" (1; #71), 0.10766503508540247),
#   ("RunPercentage" (1; #69), 0.10762024351901166),
#   ("ZoneVariance" (1; #92), 0.10744470424144496),
#   ("InterquartileRange" (1; #38), 0.10742312895682919),
#   ("SmallAreaEmphasis" (1; #77), 0.10741716200056484),
#   ("DifferenceEntropy" (1; #17), 0.10739243942771146),
#   ("LargeAreaEmphasis" (1; #44), 0.10738744468945935),
#   ("Variance" (1; #89), 0.10737515208088583),
#   ("ClusterTendency" (1; #6), 0.1073677146730958),
#   ("RobustMeanAbsoluteDeviation" (1; #64), 0.10735329094036253),
#   ("GrayLevelVariance.1" (1; #27), 0.10730810563090529),
#   ("SumSquares" (1; #86), 0.10715850193091214),
#   ("GrayLevelVariance" (1; #26), 0.10699940072295154),
#   ("JointEntropy" (1; #42), 0.10694550865903134),
#   ("MeanAbsoluteDeviation" (1; #60), 0.10678244417229822)],
#  'SUM_SCORE': [("LongRunHighGrayLevelEmphasis" (1; #51), 102860.00387594788),
#   ("90Percentile" (1; #1), 70223.4767483171),
#   ("TotalEnergy" (1; #87), 62539.29713003415),
#   ("HighGrayLevelEmphasis" (1; #29), 59704.490718875764),
#   ("LargeDependenceHighGrayLevelEmphasis" (1; #48), 58007.70816732957),
#   ("HighGrayLevelZoneEmphasis" (1; #31), 56681.75109933287),
#   ("Autocorrelation" (1; #2), 56414.11655245264),
#   ("SumAverage" (1; #84), 56355.42536484694),
#   ("Energy" (1; #19), 48640.47979850095),
#   ("Mean" (1; #59), 46744.60330162028),
#   ("Busyness" (1; #3), 46442.705339395536),
#   ("JointAverage" (1; #40), 46204.82630793575),
#   ("RootMeanSquared" (1; #65), 41292.389494345596),
#   ("GrayLevelNonUniformity.2" (1; #23), 36317.95446283561),
#   ("Median" (1; #61), 33947.37832548395),
#   ("Maximum" (1; #57), 33754.43780381568),
#   ("Coarseness" (1; #7), 32830.902142128056),
#   ("SmallAreaHighGrayLevelEmphasis" (1; #78), 30082.877405056934),
#   ("ShortRunHighGrayLevelEmphasis" (1; #72), 29242.209200480887),
#   ("Idn" (1; #35), 29190.788442170142),
#   ("Idmn" (1; #34), 24080.844781857002),
#   ("LargeAreaHighGrayLevelEmphasis" (1; #45), 21938.2486417332),
#   ("DependenceEntropy" (1; #12), 21418.85859983339),
#   ("HighGrayLevelRunEmphasis" (1; #30), 19621.72575513675),
#   ("SmallDependenceHighGrayLevelEmphasis" (1; #81), 19244.78655589408),
#   ("Imc1" (1; #36), 19093.012278459908),
#   ("Skewness" (1; #76), 14768.684487550927),
#   ("DependenceNonUniformityNormalized" (1; #14), 12874.138096570661),
#   ("Imc2" (1; #37), 12293.715458627292),
#   ("InverseVariance" (1; #39), 12011.009413700394),
#   ("DependenceNonUniformity" (1; #13), 11925.040853346207),
#   ("ShortRunLowGrayLevelEmphasis" (1; #73), 11740.59628814112),
#   ("ClusterShade" (1; #5), 11505.195880013069),
#   ("SmallDependenceLowGrayLevelEmphasis" (1; #82), 9729.091621329502),
#   ("Correlation" (1; #11), 9672.081712110874),
#   ("LowGrayLevelEmphasis" (1; #53), 9408.669905181438),
#   ("LargeDependenceLowGrayLevelEmphasis" (1; #49), 9151.181075994502),
#   ("LongRunLowGrayLevelEmphasis" (1; #52), 8755.595046462575),
#   ("LowGrayLevelRunEmphasis" (1; #54), 8466.610184729652),
#   ("LowGrayLevelZoneEmphasis" (1; #55), 8397.958763730614),
#   ("SumEntropy" (1; #85), 8245.856504850837),
#   ("Contrast.1" (1; #10), 8112.079011439388),
#   ("SmallAreaLowGrayLevelEmphasis" (1; #79), 7968.249703373893),
#   ("MCC" (1; #56), 7852.216267609233),
#   ("Minimum" (1; #62), 7786.470835354125),
#   ("Strength" (1; #83), 7695.372350335618),
#   ("Uniformity" (1; #88), 7481.32126863301),
#   ("10Percentile" (1; #0), 7349.224614772091),
#   ("GrayLevelNonUniformity" (1; #21), 7201.62937039545),
#   ("SmallDependenceEmphasis" (1; #80), 7178.997761199535),
#   ("ZoneEntropy" (1; #90), 7074.658040513198),
#   ("LargeAreaLowGrayLevelEmphasis" (1; #46), 6878.9483735786125),
#   ("Kurtosis" (1; #43), 6807.66142595103),
#   ("SizeZoneNonUniformity" (1; #74), 6784.55558303751),
#   ("Range" (1; #63), 6554.470602268087),
#   ("GrayLevelNonUniformityNormalized.1" (1; #25), 6516.750942528411),
#   ("RunEntropy" (1; #66), 6469.434566668961),
#   ("DifferenceVariance" (1; #18), 6260.492540053973),
#   ("Contrast" (1; #9), 6086.900338554951),
#   ("ZonePercentage" (1; #91), 5669.540851152277),
#   ("Entropy" (1; #20), 5467.947255007718),
#   ("DependenceVariance" (1; #15), 5433.799114269871),
#   ("Idm" (1; #33), 5332.802293986416),
#   ("RunLengthNonUniformityNormalized" (1; #68), 5283.503646395466),
#   ("LongRunEmphasis" (1; #50), 5281.050146452654),
#   ("GrayLevelNonUniformityNormalized" (1; #24), 5196.394538314371),
#   ("MaximumProbability" (1; #58), 5042.79258472157),
#   ("Complexity" (1; #8), 4935.277805544296),
#   ("GrayLevelNonUniformity.1" (1; #22), 4835.347754883904),
#   ("Id" (1; #32), 4834.015707519155),
#   ("JointEnergy" (1; #41), 4716.147588036234),
#   ("RunVariance" (1; #70), 4600.037904477783),
#   ("GrayLevelVariance.2" (1; #28), 4552.902309115357),
#   ("RunLengthNonUniformity" (1; #67), 4508.50462894608),
#   ("SizeZoneNonUniformityNormalized" (1; #75), 4239.320151733039),
#   ("LargeAreaEmphasis" (1; #44), 3973.2420512367594),
#   ("LargeDependenceEmphasis" (1; #47), 3850.606017676469),
#   ("DifferenceAverage" (1; #16), 3837.169804408414),
#   ("ClusterProminence" (1; #4), 3829.0242673351418),
#   ("DifferenceEntropy" (1; #17), 3823.726444973021),
#   ("RunPercentage" (1; #69), 3788.906518998352),
#   ("InterquartileRange" (1; #38), 3765.1883979453883),
#   ("ShortRunEmphasis" (1; #71), 3686.7024628025497),
#   ("SmallAreaEmphasis" (1; #77), 3559.110459098723),
#   ("ZoneVariance" (1; #92), 3345.355028088845),
#   ("ClusterTendency" (1; #6), 3257.437882446875),
#   ("SumSquares" (1; #86), 3239.212267047518),
#   ("Variance" (1; #89), 3179.184911368228),
#   ("GrayLevelVariance.1" (1; #27), 3130.1955041307865),
#   ("RobustMeanAbsoluteDeviation" (1; #64), 3043.746089177821),
#   ("JointEntropy" (1; #42), 2994.345709390478),
#   ("GrayLevelVariance" (1; #26), 2868.0731557442186),
#   ("MeanAbsoluteDeviation" (1; #60), 2594.510369020421)],
#  'NUM_AS_ROOT': [("LongRunHighGrayLevelEmphasis" (1; #51), 31.0),
#   ("90Percentile" (1; #1), 26.0),
#   ("HighGrayLevelZoneEmphasis" (1; #31), 23.0),
#   ("TotalEnergy" (1; #87), 23.0),
#   ("HighGrayLevelEmphasis" (1; #29), 22.0),
#   ("Autocorrelation" (1; #2), 19.0),
#   ("Energy" (1; #19), 19.0),
#   ("SumAverage" (1; #84), 19.0),
#   ("JointAverage" (1; #40), 16.0),
#   ("RootMeanSquared" (1; #65), 15.0),
#   ("Mean" (1; #59), 14.0),
#   ("ShortRunHighGrayLevelEmphasis" (1; #72), 10.0),
#   ("SmallAreaHighGrayLevelEmphasis" (1; #78), 10.0),
#   ("Maximum" (1; #57), 8.0),
#   ("Median" (1; #61), 6.0),
#   ("HighGrayLevelRunEmphasis" (1; #30), 5.0),
#   ("Busyness" (1; #3), 4.0),
#   ("SmallDependenceHighGrayLevelEmphasis" (1; #81), 4.0),
#   ("Minimum" (1; #62), 3.0),
#   ("ShortRunLowGrayLevelEmphasis" (1; #73), 3.0),
#   ("Coarseness" (1; #7), 2.0),
#   ("LowGrayLevelEmphasis" (1; #53), 2.0),
#   ("LowGrayLevelRunEmphasis" (1; #54), 2.0),
#   ("LowGrayLevelZoneEmphasis" (1; #55), 2.0),
#   ("SmallAreaLowGrayLevelEmphasis" (1; #79), 2.0),
#   ("Uniformity" (1; #88), 2.0),
#   ("10Percentile" (1; #0), 1.0),
#   ("DependenceEntropy" (1; #12), 1.0),
#   ("GrayLevelNonUniformity" (1; #21), 1.0),
#   ("Imc1" (1; #36), 1.0),
#   ("LargeDependenceHighGrayLevelEmphasis" (1; #48), 1.0),
#   ("LargeDependenceLowGrayLevelEmphasis" (1; #49), 1.0),
#   ("MCC" (1; #56), 1.0),
#   ("SmallDependenceLowGrayLevelEmphasis" (1; #82), 1.0)],
#  'NUM_NODES': [("Idn" (1; #35), 967.0),
#   ("Idmn" (1; #34), 805.0),
#   ("LargeDependenceHighGrayLevelEmphasis" (1; #48), 696.0),
#   ("Skewness" (1; #76), 648.0),
#   ("Busyness" (1; #3), 622.0),
#   ("ClusterShade" (1; #5), 602.0),
#   ("GrayLevelNonUniformity.2" (1; #23), 579.0),
#   ("Maximum" (1; #57), 559.0),
#   ("Median" (1; #61), 559.0),
#   ("LongRunHighGrayLevelEmphasis" (1; #51), 548.0),
#   ("Coarseness" (1; #7), 537.0),
#   ("Imc1" (1; #36), 449.0),
#   ("DependenceEntropy" (1; #12), 439.0),
#   ("90Percentile" (1; #1), 404.0),
#   ("Imc2" (1; #37), 402.0),
#   ("Kurtosis" (1; #43), 390.0),
#   ("Contrast.1" (1; #10), 377.0),
#   ("Correlation" (1; #11), 375.0),
#   ("LargeAreaHighGrayLevelEmphasis" (1; #45), 367.0),
#   ("SmallAreaHighGrayLevelEmphasis" (1; #78), 366.0),
#   ("SumAverage" (1; #84), 365.0),
#   ("JointAverage" (1; #40), 363.0),
#   ("Autocorrelation" (1; #2), 357.0),
#   ("Mean" (1; #59), 344.0),
#   ("HighGrayLevelZoneEmphasis" (1; #31), 336.0),
#   ("Strength" (1; #83), 326.0),
#   ("HighGrayLevelEmphasis" (1; #29), 325.0),
#   ("SmallDependenceHighGrayLevelEmphasis" (1; #81), 324.0),
#   ("DifferenceVariance" (1; #18), 323.0),
#   ("MCC" (1; #56), 320.0),
#   ("Range" (1; #63), 320.0),
#   ("TotalEnergy" (1; #87), 312.0),
#   ("ZoneEntropy" (1; #90), 295.0),
#   ("SmallDependenceLowGrayLevelEmphasis" (1; #82), 291.0),
#   ("Contrast" (1; #9), 290.0),
#   ("LargeDependenceLowGrayLevelEmphasis" (1; #49), 290.0),
#   ("LargeAreaLowGrayLevelEmphasis" (1; #46), 288.0),
#   ("Minimum" (1; #62), 285.0),
#   ("LowGrayLevelEmphasis" (1; #53), 283.0),
#   ("RootMeanSquared" (1; #65), 282.0),
#   ("SumEntropy" (1; #85), 282.0),
#   ("GrayLevelNonUniformityNormalized.1" (1; #25), 276.0),
#   ("LongRunLowGrayLevelEmphasis" (1; #52), 276.0),
#   ("HighGrayLevelRunEmphasis" (1; #30), 275.0),
#   ("ShortRunLowGrayLevelEmphasis" (1; #73), 274.0),
#   ("SmallAreaLowGrayLevelEmphasis" (1; #79), 274.0),
#   ("ShortRunHighGrayLevelEmphasis" (1; #72), 273.0),
#   ("Energy" (1; #19), 263.0),
#   ("LowGrayLevelZoneEmphasis" (1; #55), 263.0),
#   ("RunEntropy" (1; #66), 262.0),
#   ("Uniformity" (1; #88), 258.0),
#   ("DependenceNonUniformityNormalized" (1; #14), 256.0),
#   ("GrayLevelNonUniformity" (1; #21), 256.0),
#   ("Complexity" (1; #8), 255.0),
#   ("LowGrayLevelRunEmphasis" (1; #54), 254.0),
#   ("SmallDependenceEmphasis" (1; #80), 254.0),
#   ("DependenceNonUniformity" (1; #13), 251.0),
#   ("MaximumProbability" (1; #58), 251.0),
#   ("GrayLevelNonUniformityNormalized" (1; #24), 246.0),
#   ("GrayLevelVariance.2" (1; #28), 245.0),
#   ("GrayLevelNonUniformity.1" (1; #22), 244.0),
#   ("SizeZoneNonUniformity" (1; #74), 241.0),
#   ("InverseVariance" (1; #39), 240.0),
#   ("10Percentile" (1; #0), 234.0),
#   ("DependenceVariance" (1; #15), 233.0),
#   ("Entropy" (1; #20), 231.0),
#   ("InterquartileRange" (1; #38), 229.0),
#   ("RunVariance" (1; #70), 226.0),
#   ("SizeZoneNonUniformityNormalized" (1; #75), 226.0),
#   ("ClusterProminence" (1; #4), 221.0),
#   ("DifferenceAverage" (1; #16), 221.0),
#   ("SmallAreaEmphasis" (1; #77), 219.0),
#   ("JointEnergy" (1; #41), 212.0),
#   ("RunLengthNonUniformityNormalized" (1; #68), 209.0),
#   ("DifferenceEntropy" (1; #17), 207.0),
#   ("Id" (1; #32), 207.0),
#   ("ZonePercentage" (1; #91), 207.0),
#   ("LargeDependenceEmphasis" (1; #47), 199.0),
#   ("Idm" (1; #33), 195.0),
#   ("LargeAreaEmphasis" (1; #44), 192.0),
#   ("RunLengthNonUniformity" (1; #67), 189.0),
#   ("RunPercentage" (1; #69), 189.0),
#   ("SumSquares" (1; #86), 188.0),
#   ("LongRunEmphasis" (1; #50), 187.0),
#   ("GrayLevelVariance.1" (1; #27), 182.0),
#   ("JointEntropy" (1; #42), 181.0),
#   ("Variance" (1; #89), 181.0),
#   ("ZoneVariance" (1; #92), 181.0),
#   ("RobustMeanAbsoluteDeviation" (1; #64), 177.0),
#   ("GrayLevelVariance" (1; #26), 173.0),
#   ("MeanAbsoluteDeviation" (1; #60), 173.0),
#   ("ClusterTendency" (1; #6), 166.0),
#   ("ShortRunEmphasis" (1; #71), 163.0)]}

# %%
# Model self evaluation
model.make_inspector().evaluation()
# Out:
# Evaluation(num_examples=7617, accuracy=0.8856567298898255, loss=0.24741857337349626, rmse=None, ndcg=None, aucs=None, auuc=None, qini=None)

# %%
logs = model.make_inspector().training_logs()

plt.figure(figsize=(12, 4))
plt.subplot(1, 2, 1)
plt.plot([log.num_trees for log in logs], [log.evaluation.accuracy for log in logs])
plt.xlabel("Number of trees")
plt.ylabel("Accuracy (out-of-bag)")
plt.subplot(1, 2, 2)
plt.plot([log.num_trees for log in logs], [log.evaluation.loss for log in logs])
plt.xlabel("Number of trees")
plt.ylabel("Logloss (out-of-bag)")
plt.show()

# %% [markdown]
# Calculate the score of our hold-out validation dataset

# %%
predictions = model.predict(val_ds)
y_true      = validation_data["label"]

from sklearn.metrics import roc_auc_score
ROC_AUC = roc_auc_score(y_true, predictions)
print("The ROC AUC score is %.5f" % ROC_AUC )
# Out:
# 1/2 [==============>...............] - ETA: 0s
# 2/2 [==============================] - 0s 5ms/step
# The ROC AUC score is 0.99863

# %%
# Compute binary classification metrics with sklearn
import numpy as np
from sklearn.metrics import (
    accuracy_score,
    precision_score,
    recall_score,
    f1_score,
    roc_auc_score,
    average_precision_score,
    confusion_matrix,
    classification_report,
    matthews_corrcoef,
    log_loss,
    brier_score_loss,
)

# Get predictions (probabilities or class labels)
preds = model.predict(test_ds)
# If model outputs probabilities, convert to labels by threshold 0.5
if preds.ndim == 2:
    # For TFDF classification, preds may be class probabilities with shape (N, 2)
    if preds.shape[1] == 2:
        pos_probs = preds[:, 1]
    else:
        # If single-probability column (positive class)
        pos_probs = preds[:, -1]
    y_pred = (pos_probs >= 0.5).astype(int)
else:
    # Already class labels
    y_pred = preds.astype(int)
    pos_probs = None

# Ground truth labels (must be 0/1 integers)
y_true = test_data["label"].astype(int).to_numpy()

# Core metrics
metrics = {}
metrics["accuracy"] = accuracy_score(y_true, y_pred)
metrics["precision"] = precision_score(y_true, y_pred, zero_division=0)
metrics["recall"] = recall_score(y_true, y_pred, zero_division=0)
metrics["f1"] = f1_score(y_true, y_pred, zero_division=0)
metrics["mcc"] = matthews_corrcoef(y_true, y_pred)

# Probabilistic metrics (only if we have probabilities)
if pos_probs is not None:
    metrics["roc_auc"] = roc_auc_score(y_true, pos_probs)
    metrics["pr_auc"] = average_precision_score(y_true, pos_probs)
    metrics["log_loss"] = log_loss(y_true, pos_probs, labels=[0,1])
    metrics["brier_score"] = brier_score_loss(y_true, pos_probs)

# Confusion matrix and detailed report
cm = confusion_matrix(y_true, y_pred, labels=[0,1])
report = classification_report(y_true, y_pred, digits=4)

print("Sklearn binary metrics:")
for k, v in metrics.items():
    print(f"{k}: {v:.4f}")
print("\nConfusion matrix:\n", cm)
print("\nClassification report:\n", report)
# Out:
# 1/3 [=========>....................] - ETA: 0s
# 3/3 [==============================] - 0s 18ms/step
# Sklearn binary metrics:
# accuracy: 0.9676
# precision: 0.9005
# recall: 0.7577
# f1: 0.8230
# mcc: 0.8089
# roc_auc: 0.9807
# pr_auc: 0.9037
# log_loss: 0.0948
# brier_score: 0.0250
#
# Confusion matrix:
#  [[2037   19]
#  [  55  172]]
#
# Classification report:
#                precision    recall  f1-score   support
#
#            0     0.9737    0.9908    0.9822      2056
#            1     0.9005    0.7577    0.8230       227
#
#     accuracy                         0.9676      2283
#    macro avg     0.9371    0.8742    0.9026      2283
# weighted avg     0.9664    0.9676    0.9663      2283
