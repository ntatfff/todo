# %%
# Import packages and modules
import numpy  as np
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow_decision_forests as tfdf

from sklearn.model_selection import train_test_split
# Out:
# 2026-09-11 08:15:45.760430: I tensorflow/core/util/port.cc:113] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2026-09-11 08:15:45.798848: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2026-09-11 08:15:50.080395: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
# Check the version of TensorFlow Decision Forests
print("Found TensorFlow Decision Forests v" + tfdf.__version__)
# Out:
# Found TensorFlow Decision Forests v1.9.1

# %%
datasetPath = "dataset/10p/all/kernel3/"

# %%
# Parameters
datasetPath = "dataset/10p/glcm/kernel5/"

# %%
# train/validation/test = 70/10/20
train_data = pd.read_csv(f"{datasetPath}dataset.train.csv")
validation_data = pd.read_csv(f"{datasetPath}dataset.validation.csv")
test_data = pd.read_csv(f"{datasetPath}dataset.test.csv")

# %%
from sklearn.utils.class_weight import compute_class_weight

# tinh class weight tren tap train
classes = np.array([0, 1])
weights = compute_class_weight(class_weight="balanced", classes=classes, y=train_data["label"])
class_weight = {0: weights[0], 1: weights[1]}

# gan sample_weight cho tung dong
train_data["sample_weight"] = train_data["label"].map(class_weight)
validation_data["sample_weight"] = validation_data["label"].map(class_weight)
test_data["sample_weight"] = test_data["label"].map(class_weight)

# Convert the dataset into a TensorFlow dataset.
train_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    train_data, label="label", weight="sample_weight"
)         
val_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    validation_data, label="label", weight="sample_weight"
)
test_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    test_data, label="label", weight="sample_weight"
)
# Out:
# 2026-09-11 08:16:03.276519: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:984] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2026-09-11 08:16:03.278545: W tensorflow/core/common_runtime/gpu/gpu_device.cc:2251] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...

# %%
import keras

# %%
# %%time

# Train a Gradient Boosted Trees model.
model = tfdf.keras.GradientBoostedTreesModel()

# Add evaluation metrics
model.compile(
    metrics=["accuracy"]
)
model.fit(x=train_ds)

# # Train a Gradient Boosted Trees model.
# model = tfdf.keras.GradientBoostedTreesModel(num_trees=1500)
# model.fit(train_ds)
# Out:
# Use /tmp/tmpfoxo7ha0 as temporary training directory
# Reading training dataset...
# [WARNING 26-09-11 08:16:03.4067 UTC gradient_boosted_trees.cc:1840] "goss_alpha" set but "sampling_method" not equal to "GOSS".
# [WARNING 26-09-11 08:16:03.4067 UTC gradient_boosted_trees.cc:1851] "goss_beta" set but "sampling_method" not equal to "GOSS".
# [WARNING 26-09-11 08:16:03.4067 UTC gradient_boosted_trees.cc:1865] "selective_gradient_boosting_ratio" set but "sampling_method" not equal to "SELGB".
# Training dataset read in 0:00:02.582636. Found 7617 examples.
# Training model...
# Model trained in 0:00:00.786372
# Compiling model...
# [INFO 26-09-11 08:16:06.7976 UTC kernel.cc:1233] Loading model from path /tmp/tmpfoxo7ha0/model/ with prefix a08eb817384f4aac
# [INFO 26-09-11 08:16:06.7998 UTC quick_scorer_extended.cc:911] The binary was compiled without AVX2 support, but your CPU supports it. Enable it for faster model inference.
# [INFO 26-09-11 08:16:06.8000 UTC abstract_model.cc:1362] Engine "GradientBoostedTreesQuickScorerExtended" built
# [INFO 26-09-11 08:16:06.8000 UTC kernel.cc:1061] Use fast generic engine
# Model compiled.
# CPU times: user 8.92 s, sys: 641 ms, total: 9.57 s
# Wall time: 6.45 s

# %%
# Evaluate the model
evaluate = model.evaluate(val_ds, return_dict=True)
print()

for name, value in evaluate.items():
    print(f"{name}: {value:.4f}")
# Out:
# WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 1/2 [==============>...............] - ETA: 3s - loss: 0.0000e+00 - accuracy: 0.9910
# 2/2 [==============================] - 3s 8ms/step - loss: 0.0000e+00 - accuracy: 0.9916
# loss: 0.0000
# accuracy: 0.9916

# %%
# Model Summary
model.summary()
# Out:
# Model: "gradient_boosted_trees_model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
# =================================================================
# Total params: 1 (1.00 Byte)
# Trainable params: 0 (0.00 Byte)
# Non-trainable params: 1 (1.00 Byte)
# _________________________________________________________________
# Type: "GRADIENT_BOOSTED_TREES"
# Task: CLASSIFICATION
# Label: "__LABEL"
#
# Input Features (24):
# 	Autocorrelation
# 	ClusterProminence
# 	ClusterShade
# 	ClusterTendency
# 	Contrast
# 	Correlation
# 	DifferenceAverage
# 	DifferenceEntropy
# 	DifferenceVariance
# 	Id
# 	Idm
# 	Idmn
# 	Idn
# 	Imc1
# 	Imc2
# 	InverseVariance
# 	JointAverage
# 	JointEnergy
# 	JointEntropy
# 	MCC
# 	MaximumProbability
# 	SumAverage
# 	SumEntropy
# 	SumSquares
#
# Trained with weights
#
# Variable Importance: INV_MEAN_MIN_DEPTH:
#     1.    "Autocorrelation"  0.284390 ################
#     2.         "SumAverage"  0.279248 ###############
#     3.       "JointAverage"  0.244928 ##########
#     4.    "InverseVariance"  0.216048 ######
#     5.               "Imc1"  0.208600 #####
#     6.       "ClusterShade"  0.195024 ###
#     7.                "Idn"  0.190948 ##
#     8.               "Imc2"  0.183684 #
#     9.               "Idmn"  0.181616 #
#    10.        "Correlation"  0.181053 #
#    11. "DifferenceVariance"  0.179604 #
#    12.           "Contrast"  0.179134 #
#    13.                "MCC"  0.177821
#    14.         "SumEntropy"  0.177786
#    15. "MaximumProbability"  0.177066
#    16.                "Idm"  0.176764
#    17.                 "Id"  0.176707
#    18.  "ClusterProminence"  0.173517
#    19.  "DifferenceAverage"  0.173470
#    20.        "JointEnergy"  0.173289
#    21.    "ClusterTendency"  0.172202
#    22.       "JointEntropy"  0.172111
#    23.  "DifferenceEntropy"  0.171729
#    24.         "SumSquares"  0.171391
#
# Variable Importance: NUM_AS_ROOT:
#     1.      "SumAverage" 16.000000 ################
#     2. "Autocorrelation" 13.000000 ############
#     3.    "JointAverage" 12.000000 ###########
#     4.     "Correlation"  1.000000
#     5.            "Imc1"  1.000000
#
# Variable Importance: NUM_NODES:
#     1.    "Autocorrelation" 156.000000 ################
#     2.       "ClusterShade" 120.000000 ############
#     3.                "Idn" 96.000000 #########
#     4.    "InverseVariance" 79.000000 #######
#     5.         "SumAverage" 76.000000 #######
#     6.               "Imc1" 72.000000 ######
#     7.       "JointAverage" 69.000000 ######
#     8.               "Imc2" 59.000000 #####
#     9.               "Idmn" 58.000000 #####
#    10. "DifferenceVariance" 38.000000 ###
#    11. "MaximumProbability" 38.000000 ###
#    12.         "SumEntropy" 36.000000 ###
#    13.                "MCC" 34.000000 ##
#    14.        "Correlation" 31.000000 ##
#    15.           "Contrast" 27.000000 ##
#    16.                "Idm" 23.000000 #
#    17.  "ClusterProminence" 19.000000 #
#    18.        "JointEnergy" 18.000000 #
#    19.  "DifferenceAverage" 16.000000
#    20.                 "Id" 15.000000
#    21.  "DifferenceEntropy" 12.000000
#    22.       "JointEntropy" 12.000000
#    23.    "ClusterTendency" 11.000000
#    24.         "SumSquares"  8.000000
#
# Variable Importance: SUM_SCORE:
#     1.    "Autocorrelation" 2766.052603 ################
#     2.         "SumAverage" 2215.200924 ############
#     3.    "InverseVariance" 705.276225 ####
#     4.       "JointAverage" 500.962027 ##
#     5.               "Imc1" 428.753196 ##
#     6.                "Idn" 388.161989 ##
#     7.               "Idmn" 308.071473 #
#     8.               "Imc2" 221.532027 #
#     9.       "ClusterShade" 207.257919 #
#    10.           "Contrast" 122.738539
#    11.         "SumEntropy" 106.110866
#    12.                "MCC" 89.266566
#    13. "MaximumProbability" 80.239089
#    14. "DifferenceVariance" 77.194050
#    15.  "DifferenceAverage" 68.855981
#    16.                "Idm" 64.859441
#    17.        "Correlation" 62.148759
#    18.  "DifferenceEntropy" 44.734045
#    19.  "ClusterProminence" 44.641043
#    20.                 "Id" 32.683122
#    21.        "JointEnergy" 31.033180
#    22.       "JointEntropy" 21.784147
#    23.    "ClusterTendency" 13.595467
#    24.         "SumSquares"  5.666671
#
#
#
# Loss: BINOMIAL_LOG_LIKELIHOOD
# Validation loss value: 0.534075
# Number of trees per iteration: 1
# Node format: NOT_SET
# Number of trees: 43
# Total number of nodes: 2289
#
# Number of nodes by tree:
# Count: 43 Average: 53.2326 StdDev: 7.22025
# Min: 35 Max: 63 Ignored: 0
# ----------------------------------------------
# [ 35, 36) 1   2.33%   2.33% #
# [ 36, 37) 0   0.00%   2.33%
# [ 37, 39) 2   4.65%   6.98% ##
# [ 39, 40) 0   0.00%   6.98%
# [ 40, 42) 0   0.00%   6.98%
# [ 42, 43) 0   0.00%   6.98%
# [ 43, 45) 4   9.30%  16.28% ####
# [ 45, 46) 1   2.33%  18.60% #
# [ 46, 48) 3   6.98%  25.58% ###
# [ 48, 49) 0   0.00%  25.58%
# [ 49, 50) 2   4.65%  30.23% ##
# [ 50, 52) 0   0.00%  30.23%
# [ 52, 53) 0   0.00%  30.23%
# [ 53, 55) 4   9.30%  39.53% ####
# [ 55, 56) 4   9.30%  48.84% ####
# [ 56, 58) 9  20.93%  69.77% ##########
# [ 58, 59) 0   0.00%  69.77%
# [ 59, 61) 8  18.60%  88.37% #########
# [ 61, 62) 4   9.30%  97.67% ####
# [ 62, 63] 1   2.33% 100.00% #
#
# Depth by leafs:
# Count: 1166 Average: 4.86621 StdDev: 0.443293
# Min: 2 Max: 5 Ignored: 0
# ----------------------------------------------
# [ 2, 3)    7   0.60%   0.60%
# [ 3, 4)   26   2.23%   2.83%
# [ 4, 5)   83   7.12%   9.95% #
# [ 5, 5] 1050  90.05% 100.00% ##########
#
# Number of training obs by leaf:
# Count: 1166 Average: 253.316 StdDev: 531.662
# Min: 5 Max: 5463 Ignored: 0
# ----------------------------------------------
# [    5,  277) 925  79.33%  79.33% ##########
# [  277,  550)  95   8.15%  87.48% #
# [  550,  823)  46   3.95%  91.42%
# [  823, 1096)  20   1.72%  93.14%
# [ 1096, 1369)  23   1.97%  95.11%
# [ 1369, 1642)  15   1.29%  96.40%
# [ 1642, 1915)   7   0.60%  97.00%
# [ 1915, 2188)  15   1.29%  98.28%
# [ 2188, 2461)   4   0.34%  98.63%
# [ 2461, 2734)   5   0.43%  99.06%
# [ 2734, 3007)   5   0.43%  99.49%
# [ 3007, 3280)   2   0.17%  99.66%
# [ 3280, 3553)   2   0.17%  99.83%
# [ 3553, 3826)   0   0.00%  99.83%
# [ 3826, 4099)   1   0.09%  99.91%
# [ 4099, 4372)   0   0.00%  99.91%
# [ 4372, 4645)   0   0.00%  99.91%
# [ 4645, 4918)   0   0.00%  99.91%
# [ 4918, 5191)   0   0.00%  99.91%
# [ 5191, 5463]   1   0.09% 100.00%
#
# Attribute in nodes:
# 	156 : Autocorrelation [NUMERICAL]
# 	120 : ClusterShade [NUMERICAL]
# 	96 : Idn [NUMERICAL]
# 	79 : InverseVariance [NUMERICAL]
# 	76 : SumAverage [NUMERICAL]
# 	72 : Imc1 [NUMERICAL]
# 	69 : JointAverage [NUMERICAL]
# 	59 : Imc2 [NUMERICAL]
# 	58 : Idmn [NUMERICAL]
# 	38 : MaximumProbability [NUMERICAL]
# 	38 : DifferenceVariance [NUMERICAL]
# 	36 : SumEntropy [NUMERICAL]
# 	34 : MCC [NUMERICAL]
# 	31 : Correlation [NUMERICAL]
# 	27 : Contrast [NUMERICAL]
# 	23 : Idm [NUMERICAL]
# 	19 : ClusterProminence [NUMERICAL]
# 	18 : JointEnergy [NUMERICAL]
# 	16 : DifferenceAverage [NUMERICAL]
# 	15 : Id [NUMERICAL]
# 	12 : JointEntropy [NUMERICAL]
# 	12 : DifferenceEntropy [NUMERICAL]
# 	11 : ClusterTendency [NUMERICAL]
# 	8 : SumSquares [NUMERICAL]
#
# Attribute in nodes with depth <= 0:
# 	16 : SumAverage [NUMERICAL]
# 	13 : Autocorrelation [NUMERICAL]
# 	12 : JointAverage [NUMERICAL]
# 	1 : Imc1 [NUMERICAL]
# 	1 : Correlation [NUMERICAL]
#
# Attribute in nodes with depth <= 1:
# 	28 : SumAverage [NUMERICAL]
# 	28 : Autocorrelation [NUMERICAL]
# 	18 : JointAverage [NUMERICAL]
# 	17 : InverseVariance [NUMERICAL]
# 	14 : Imc1 [NUMERICAL]
# 	4 : ClusterShade [NUMERICAL]
# 	3 : Idn [NUMERICAL]
# 	3 : Id [NUMERICAL]
# 	3 : Contrast [NUMERICAL]
# 	2 : Idmn [NUMERICAL]
# 	2 : Idm [NUMERICAL]
# 	2 : DifferenceVariance [NUMERICAL]
# 	2 : Correlation [NUMERICAL]
# 	1 : MCC [NUMERICAL]
# 	1 : Imc2 [NUMERICAL]
# 	1 : DifferenceAverage [NUMERICAL]
#
# Attribute in nodes with depth <= 2:
# 	60 : Autocorrelation [NUMERICAL]
# 	33 : SumAverage [NUMERICAL]
# 	32 : InverseVariance [NUMERICAL]
# 	31 : Imc1 [NUMERICAL]
# 	26 : JointAverage [NUMERICAL]
# 	19 : ClusterShade [NUMERICAL]
# 	13 : Imc2 [NUMERICAL]
# 	12 : Idn [NUMERICAL]
# 	9 : DifferenceVariance [NUMERICAL]
# 	8 : SumEntropy [NUMERICAL]
# 	7 : MCC [NUMERICAL]
# 	7 : Idmn [NUMERICAL]
# 	7 : Correlation [NUMERICAL]
# 	6 : MaximumProbability [NUMERICAL]
# 	6 : Idm [NUMERICAL]
# 	5 : Contrast [NUMERICAL]
# 	4 : Id [NUMERICAL]
# 	4 : DifferenceAverage [NUMERICAL]
# 	2 : JointEnergy [NUMERICAL]
# 	1 : JointEntropy [NUMERICAL]
# 	1 : DifferenceEntropy [NUMERICAL]
# 	1 : ClusterTendency [NUMERICAL]
#
# Attribute in nodes with depth <= 3:
# 	92 : Autocorrelation [NUMERICAL]
# 	77 : ClusterShade [NUMERICAL]
# 	52 : InverseVariance [NUMERICAL]
# 	49 : SumAverage [NUMERICAL]
# 	41 : Imc1 [NUMERICAL]
# 	40 : Idn [NUMERICAL]
# 	36 : JointAverage [NUMERICAL]
# 	30 : Imc2 [NUMERICAL]
# 	26 : Idmn [NUMERICAL]
# 	19 : SumEntropy [NUMERICAL]
# 	19 : MaximumProbability [NUMERICAL]
# 	17 : DifferenceVariance [NUMERICAL]
# 	17 : Contrast [NUMERICAL]
# 	15 : Correlation [NUMERICAL]
# 	13 : ClusterProminence [NUMERICAL]
# 	12 : MCC [NUMERICAL]
# 	12 : Idm [NUMERICAL]
# 	9 : JointEnergy [NUMERICAL]
# 	6 : Id [NUMERICAL]
# 	6 : DifferenceAverage [NUMERICAL]
# 	6 : ClusterTendency [NUMERICAL]
# 	2 : JointEntropy [NUMERICAL]
# 	1 : SumSquares [NUMERICAL]
# 	1 : DifferenceEntropy [NUMERICAL]
#
# Attribute in nodes with depth <= 5:
# 	156 : Autocorrelation [NUMERICAL]
# 	120 : ClusterShade [NUMERICAL]
# 	96 : Idn [NUMERICAL]
# 	79 : InverseVariance [NUMERICAL]
# 	76 : SumAverage [NUMERICAL]
# 	72 : Imc1 [NUMERICAL]
# 	69 : JointAverage [NUMERICAL]
# 	59 : Imc2 [NUMERICAL]
# 	58 : Idmn [NUMERICAL]
# 	38 : MaximumProbability [NUMERICAL]
# 	38 : DifferenceVariance [NUMERICAL]
# 	36 : SumEntropy [NUMERICAL]
# 	34 : MCC [NUMERICAL]
# 	31 : Correlation [NUMERICAL]
# 	27 : Contrast [NUMERICAL]
# 	23 : Idm [NUMERICAL]
# 	19 : ClusterProminence [NUMERICAL]
# 	18 : JointEnergy [NUMERICAL]
# 	16 : DifferenceAverage [NUMERICAL]
# 	15 : Id [NUMERICAL]
# 	12 : JointEntropy [NUMERICAL]
# 	12 : DifferenceEntropy [NUMERICAL]
# 	11 : ClusterTendency [NUMERICAL]
# 	8 : SumSquares [NUMERICAL]
#
# Condition type in nodes:
# 	1123 : HigherCondition
# Condition type in nodes with depth <= 0:
# 	43 : HigherCondition
# Condition type in nodes with depth <= 1:
# 	129 : HigherCondition
# Condition type in nodes with depth <= 2:
# 	294 : HigherCondition
# Condition type in nodes with depth <= 3:
# 	598 : HigherCondition
# Condition type in nodes with depth <= 5:
# 	1123 : HigherCondition
#
# Training logs:
# Number of iteration to final model: 43
# 	Iter:1 train-loss:1.243467 valid-loss:1.268327  train-accuracy:0.910665 valid-accuracy:0.848963
# 	Iter:2 train-loss:1.117924 valid-loss:1.165088  train-accuracy:0.939134 valid-accuracy:0.875574
# 	Iter:3 train-loss:1.015788 valid-loss:1.095125  train-accuracy:0.941837 valid-accuracy:0.810647
# 	Iter:4 train-loss:0.930952 valid-loss:1.027350  train-accuracy:0.944432 valid-accuracy:0.809983
# 	Iter:5 train-loss:0.853201 valid-loss:0.961125  train-accuracy:0.949824 valid-accuracy:0.854937
# 	Iter:6 train-loss:0.785864 valid-loss:0.914363  train-accuracy:0.955650 valid-accuracy:0.847938
# 	Iter:16 train-loss:0.405896 valid-loss:0.643638  train-accuracy:0.970654 valid-accuracy:0.847576
# 	Iter:26 train-loss:0.258281 valid-loss:0.549370  train-accuracy:0.977921 valid-accuracy:0.852223
# 	Iter:36 train-loss:0.184426 valid-loss:0.544224  train-accuracy:0.987199 valid-accuracy:0.865196
# 	Iter:46 train-loss:0.139272 valid-loss:0.536915  train-accuracy:0.992348 valid-accuracy:0.864533
# 	Iter:56 train-loss:0.105810 valid-loss:0.547939  train-accuracy:0.994901 valid-accuracy:0.856869
# 	Iter:66 train-loss:0.086775 valid-loss:0.558398  train-accuracy:0.995921 valid-accuracy:0.867851

# %%
# Model features
model.make_inspector().features()
# Out:
# ["Autocorrelation" (1; #0),
#  "ClusterProminence" (1; #1),
#  "ClusterShade" (1; #2),
#  "ClusterTendency" (1; #3),
#  "Contrast" (1; #4),
#  "Correlation" (1; #5),
#  "DifferenceAverage" (1; #6),
#  "DifferenceEntropy" (1; #7),
#  "DifferenceVariance" (1; #8),
#  "Id" (1; #9),
#  "Idm" (1; #10),
#  "Idmn" (1; #11),
#  "Idn" (1; #12),
#  "Imc1" (1; #13),
#  "Imc2" (1; #14),
#  "InverseVariance" (1; #15),
#  "JointAverage" (1; #16),
#  "JointEnergy" (1; #17),
#  "JointEntropy" (1; #18),
#  "MCC" (1; #19),
#  "MaximumProbability" (1; #20),
#  "SumAverage" (1; #21),
#  "SumEntropy" (1; #22),
#  "SumSquares" (1; #23)]

# %%
# Feature importance
model.make_inspector().variable_importances()
# Out:
# {'INV_MEAN_MIN_DEPTH': [("Autocorrelation" (1; #0), 0.28438996947377476),
#   ("SumAverage" (1; #21), 0.27924836666781944),
#   ("JointAverage" (1; #16), 0.24492799548364014),
#   ("InverseVariance" (1; #15), 0.21604774723712167),
#   ("Imc1" (1; #13), 0.2085997343743978),
#   ("ClusterShade" (1; #2), 0.19502401492286425),
#   ("Idn" (1; #12), 0.19094775400490588),
#   ("Imc2" (1; #14), 0.18368362213727119),
#   ("Idmn" (1; #11), 0.1816158181176213),
#   ("Correlation" (1; #5), 0.18105275025803427),
#   ("DifferenceVariance" (1; #8), 0.17960399157874316),
#   ("Contrast" (1; #4), 0.1791342821923591),
#   ("MCC" (1; #19), 0.17782108663338606),
#   ("SumEntropy" (1; #22), 0.17778556518839822),
#   ("MaximumProbability" (1; #20), 0.17706593607883436),
#   ("Idm" (1; #10), 0.17676436152265526),
#   ("Id" (1; #9), 0.17670714587795242),
#   ("ClusterProminence" (1; #1), 0.17351683687653854),
#   ("DifferenceAverage" (1; #6), 0.1734696119935787),
#   ("JointEnergy" (1; #17), 0.17328933530992935),
#   ("ClusterTendency" (1; #3), 0.1722018891457902),
#   ("JointEntropy" (1; #18), 0.17211098615097684),
#   ("DifferenceEntropy" (1; #7), 0.17172913455097177),
#   ("SumSquares" (1; #23), 0.17139069744667934)],
#  'NUM_AS_ROOT': [("SumAverage" (1; #21), 16.0),
#   ("Autocorrelation" (1; #0), 13.0),
#   ("JointAverage" (1; #16), 12.0),
#   ("Correlation" (1; #5), 1.0),
#   ("Imc1" (1; #13), 1.0)],
#  'SUM_SCORE': [("Autocorrelation" (1; #0), 2766.052603315745),
#   ("SumAverage" (1; #21), 2215.200924391741),
#   ("InverseVariance" (1; #15), 705.2762249989207),
#   ("JointAverage" (1; #16), 500.96202661072834),
#   ("Imc1" (1; #13), 428.7531961837799),
#   ("Idn" (1; #12), 388.1619894214256),
#   ("Idmn" (1; #11), 308.07147275908045),
#   ("Imc2" (1; #14), 221.53202721564944),
#   ("ClusterShade" (1; #2), 207.2579189735173),
#   ("Contrast" (1; #4), 122.73853891628305),
#   ("SumEntropy" (1; #22), 106.11086556520642),
#   ("MCC" (1; #19), 89.2665660097932),
#   ("MaximumProbability" (1; #20), 80.23908858614298),
#   ("DifferenceVariance" (1; #8), 77.1940500440251),
#   ("DifferenceAverage" (1; #6), 68.8559814325355),
#   ("Idm" (1; #10), 64.85944115719458),
#   ("Correlation" (1; #5), 62.14875856042351),
#   ("DifferenceEntropy" (1; #7), 44.734044589896826),
#   ("ClusterProminence" (1; #1), 44.641042870051635),
#   ("Id" (1; #9), 32.68312237409211),
#   ("JointEnergy" (1; #17), 31.033180136160198),
#   ("JointEntropy" (1; #18), 21.78414735573643),
#   ("ClusterTendency" (1; #3), 13.59546718534781),
#   ("SumSquares" (1; #23), 5.6666706397557025)],
#  'NUM_NODES': [("Autocorrelation" (1; #0), 156.0),
#   ("ClusterShade" (1; #2), 120.0),
#   ("Idn" (1; #12), 96.0),
#   ("InverseVariance" (1; #15), 79.0),
#   ("SumAverage" (1; #21), 76.0),
#   ("Imc1" (1; #13), 72.0),
#   ("JointAverage" (1; #16), 69.0),
#   ("Imc2" (1; #14), 59.0),
#   ("Idmn" (1; #11), 58.0),
#   ("DifferenceVariance" (1; #8), 38.0),
#   ("MaximumProbability" (1; #20), 38.0),
#   ("SumEntropy" (1; #22), 36.0),
#   ("MCC" (1; #19), 34.0),
#   ("Correlation" (1; #5), 31.0),
#   ("Contrast" (1; #4), 27.0),
#   ("Idm" (1; #10), 23.0),
#   ("ClusterProminence" (1; #1), 19.0),
#   ("JointEnergy" (1; #17), 18.0),
#   ("DifferenceAverage" (1; #6), 16.0),
#   ("Id" (1; #9), 15.0),
#   ("DifferenceEntropy" (1; #7), 12.0),
#   ("JointEntropy" (1; #18), 12.0),
#   ("ClusterTendency" (1; #3), 11.0),
#   ("SumSquares" (1; #23), 8.0)]}

# %%
# Model self evaluation
model.make_inspector().evaluation()
# Out:
# Evaluation(num_examples=None, accuracy=0.8555416464805603, loss=0.5340753197669983, rmse=None, ndcg=None, aucs=None, auuc=None, qini=None)

# %%
logs = model.make_inspector().training_logs()

plt.figure(figsize=(12, 4))
plt.subplot(1, 2, 1)
plt.plot([log.num_trees for log in logs], [log.evaluation.accuracy for log in logs])
plt.xlabel("Number of trees")
plt.ylabel("Accuracy (out-of-bag)")
plt.subplot(1, 2, 2)
plt.plot([log.num_trees for log in logs], [log.evaluation.loss for log in logs])
plt.xlabel("Number of trees")
plt.ylabel("Logloss (out-of-bag)")
plt.show()

# %% [markdown]
# Calculate the score of our hold-out validation dataset

# %%
predictions = model.predict(val_ds)
y_true      = validation_data["label"]

from sklearn.metrics import roc_auc_score
ROC_AUC = roc_auc_score(y_true, predictions)
print("The ROC AUC score is %.5f" % ROC_AUC )
# Out:
# 1/2 [==============>...............] - ETA: 0s
# 2/2 [==============================] - 0s 3ms/step
# The ROC AUC score is 0.99443

# %%
# Compute binary classification metrics with sklearn
import numpy as np
from sklearn.metrics import (
    accuracy_score,
    precision_score,
    recall_score,
    f1_score,
    roc_auc_score,
    average_precision_score,
    confusion_matrix,
    classification_report,
    matthews_corrcoef,
    log_loss,
    brier_score_loss,
)

# Get predictions (probabilities or class labels)
preds = model.predict(test_ds)
# If model outputs probabilities, convert to labels by threshold 0.5
if preds.ndim == 2:
    # For TFDF classification, preds may be class probabilities with shape (N, 2)
    if preds.shape[1] == 2:
        pos_probs = preds[:, 1]
    else:
        # If single-probability column (positive class)
        pos_probs = preds[:, -1]
    y_pred = (pos_probs >= 0.5).astype(int)
else:
    # Already class labels
    y_pred = preds.astype(int)
    pos_probs = None

# Ground truth labels (must be 0/1 integers)
y_true = test_data["label"].astype(int).to_numpy()

# Core metrics
metrics = {}
metrics["accuracy"] = accuracy_score(y_true, y_pred)
metrics["precision"] = precision_score(y_true, y_pred, zero_division=0)
metrics["recall"] = recall_score(y_true, y_pred, zero_division=0)
metrics["f1"] = f1_score(y_true, y_pred, zero_division=0)
metrics["mcc"] = matthews_corrcoef(y_true, y_pred)

# Probabilistic metrics (only if we have probabilities)
if pos_probs is not None:
    metrics["roc_auc"] = roc_auc_score(y_true, pos_probs)
    metrics["pr_auc"] = average_precision_score(y_true, pos_probs)
    metrics["log_loss"] = log_loss(y_true, pos_probs, labels=[0,1])
    metrics["brier_score"] = brier_score_loss(y_true, pos_probs)

# Confusion matrix and detailed report
cm = confusion_matrix(y_true, y_pred, labels=[0,1])
report = classification_report(y_true, y_pred, digits=4)

print("Sklearn binary metrics:")
for k, v in metrics.items():
    print(f"{k}: {v:.4f}")
print("\nConfusion matrix:\n", cm)
print("\nClassification report:\n", report)
# Out:
# 1/3 [=========>....................] - ETA: 0s
# 3/3 [==============================] - 0s 5ms/step
# Sklearn binary metrics:
# accuracy: 0.9580
# precision: 0.7631
# recall: 0.8370
# f1: 0.7983
# mcc: 0.7759
# roc_auc: 0.9748
# pr_auc: 0.8882
# log_loss: 0.1348
# brier_score: 0.0334
#
# Confusion matrix:
#  [[1997   59]
#  [  37  190]]
#
# Classification report:
#                precision    recall  f1-score   support
#
#            0     0.9818    0.9713    0.9765      2056
#            1     0.7631    0.8370    0.7983       227
#
#     accuracy                         0.9580      2283
#    macro avg     0.8724    0.9042    0.8874      2283
# weighted avg     0.9601    0.9580    0.9588      2283
