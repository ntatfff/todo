# %%
# Import packages and modules
import numpy  as np
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow_decision_forests as tfdf

from sklearn.model_selection import train_test_split
# Out:
# 2026-09-11 08:16:53.573824: I tensorflow/core/util/port.cc:113] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2026-09-11 08:16:53.613190: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2026-09-11 08:16:57.888470: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
# Check the version of TensorFlow Decision Forests
print("Found TensorFlow Decision Forests v" + tfdf.__version__)
# Out:
# Found TensorFlow Decision Forests v1.9.1

# %%
datasetPath = "dataset/10p/all/kernel3/"

# %%
# Parameters
datasetPath = "dataset/10p/glrlm/kernel5/"

# %%
# train/validation/test = 70/10/20
train_data = pd.read_csv(f"{datasetPath}dataset.train.csv")
validation_data = pd.read_csv(f"{datasetPath}dataset.validation.csv")
test_data = pd.read_csv(f"{datasetPath}dataset.test.csv")

# %%
from sklearn.utils.class_weight import compute_class_weight

# tinh class weight tren tap train
classes = np.array([0, 1])
weights = compute_class_weight(class_weight="balanced", classes=classes, y=train_data["label"])
class_weight = {0: weights[0], 1: weights[1]}

# gan sample_weight cho tung dong
train_data["sample_weight"] = train_data["label"].map(class_weight)
validation_data["sample_weight"] = validation_data["label"].map(class_weight)
test_data["sample_weight"] = test_data["label"].map(class_weight)

# Convert the dataset into a TensorFlow dataset.
train_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    train_data, label="label", weight="sample_weight"
)         
val_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    validation_data, label="label", weight="sample_weight"
)
test_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    test_data, label="label", weight="sample_weight"
)
# Out:
# 2026-09-11 08:17:10.709239: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:984] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2026-09-11 08:17:10.710650: W tensorflow/core/common_runtime/gpu/gpu_device.cc:2251] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...

# %%
import keras

# %%
# %%time

# Train a Gradient Boosted Trees model.
model = tfdf.keras.GradientBoostedTreesModel()

# Add evaluation metrics
model.compile(
    metrics=["accuracy"]
)
model.fit(x=train_ds)

# # Train a Gradient Boosted Trees model.
# model = tfdf.keras.GradientBoostedTreesModel(num_trees=1500)
# model.fit(train_ds)
# Out:
# Use /tmp/tmpp3v8vxdo as temporary training directory
# Reading training dataset...
# [WARNING 26-09-11 08:17:10.8253 UTC gradient_boosted_trees.cc:1840] "goss_alpha" set but "sampling_method" not equal to "GOSS".
# [WARNING 26-09-11 08:17:10.8253 UTC gradient_boosted_trees.cc:1851] "goss_beta" set but "sampling_method" not equal to "GOSS".
# [WARNING 26-09-11 08:17:10.8253 UTC gradient_boosted_trees.cc:1865] "selective_gradient_boosting_ratio" set but "sampling_method" not equal to "SELGB".
# Training dataset read in 0:00:02.515768. Found 7617 examples.
# Training model...
# Model trained in 0:00:00.766617
# Compiling model...
# [INFO 26-09-11 08:17:14.1278 UTC kernel.cc:1233] Loading model from path /tmp/tmpp3v8vxdo/model/ with prefix 69e646af4c6f46df
# [INFO 26-09-11 08:17:14.1307 UTC quick_scorer_extended.cc:911] The binary was compiled without AVX2 support, but your CPU supports it. Enable it for faster model inference.
# [INFO 26-09-11 08:17:14.1309 UTC abstract_model.cc:1362] Engine "GradientBoostedTreesQuickScorerExtended" built
# [INFO 26-09-11 08:17:14.1310 UTC kernel.cc:1061] Use fast generic engine
# Model compiled.
# CPU times: user 8.2 s, sys: 663 ms, total: 8.87 s
# Wall time: 6.29 s

# %%
# Evaluate the model
evaluate = model.evaluate(val_ds, return_dict=True)
print()

for name, value in evaluate.items():
    print(f"{name}: {value:.4f}")
# Out:
# WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 1/2 [==============>...............] - ETA: 2s - loss: 0.0000e+00 - accuracy: 0.9800
# 2/2 [==============================] - 3s 7ms/step - loss: 0.0000e+00 - accuracy: 0.9814
# loss: 0.0000
# accuracy: 0.9814

# %%
# Model Summary
model.summary()
# Out:
# Model: "gradient_boosted_trees_model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
# =================================================================
# Total params: 1 (1.00 Byte)
# Trainable params: 0 (0.00 Byte)
# Non-trainable params: 1 (1.00 Byte)
# _________________________________________________________________
# Type: "GRADIENT_BOOSTED_TREES"
# Task: CLASSIFICATION
# Label: "__LABEL"
#
# Input Features (16):
# 	GrayLevelNonUniformity
# 	GrayLevelNonUniformityNormalized
# 	GrayLevelVariance
# 	HighGrayLevelRunEmphasis
# 	LongRunEmphasis
# 	LongRunHighGrayLevelEmphasis
# 	LongRunLowGrayLevelEmphasis
# 	LowGrayLevelRunEmphasis
# 	RunEntropy
# 	RunLengthNonUniformity
# 	RunLengthNonUniformityNormalized
# 	RunPercentage
# 	RunVariance
# 	ShortRunEmphasis
# 	ShortRunHighGrayLevelEmphasis
# 	ShortRunLowGrayLevelEmphasis
#
# Trained with weights
#
# Variable Importance: INV_MEAN_MIN_DEPTH:
#     1.     "LongRunHighGrayLevelEmphasis"  0.503884 ################
#     2.                       "RunEntropy"  0.211214 #
#     3.     "ShortRunLowGrayLevelEmphasis"  0.199727 #
#     4.         "HighGrayLevelRunEmphasis"  0.197989 #
#     5.      "LongRunLowGrayLevelEmphasis"  0.196125
#     6.    "ShortRunHighGrayLevelEmphasis"  0.192030
#     7. "RunLengthNonUniformityNormalized"  0.190277
#     8. "GrayLevelNonUniformityNormalized"  0.186984
#     9.                "GrayLevelVariance"  0.185688
#    10.           "GrayLevelNonUniformity"  0.183604
#    11.                      "RunVariance"  0.183521
#    12.          "LowGrayLevelRunEmphasis"  0.183428
#    13.           "RunLengthNonUniformity"  0.181671
#    14.                    "RunPercentage"  0.180932
#    15.                 "ShortRunEmphasis"  0.176229
#    16.                  "LongRunEmphasis"  0.176019
#
# Variable Importance: NUM_AS_ROOT:
#     1. "LongRunHighGrayLevelEmphasis" 45.000000 ################
#     2.  "LongRunLowGrayLevelEmphasis"  4.000000 #
#     3.     "HighGrayLevelRunEmphasis"  3.000000
#     4.                   "RunEntropy"  3.000000
#     5. "ShortRunLowGrayLevelEmphasis"  2.000000
#     6.       "GrayLevelNonUniformity"  1.000000
#     7.      "LowGrayLevelRunEmphasis"  1.000000
#     8.                  "RunVariance"  1.000000
#
# Variable Importance: NUM_NODES:
#     1.     "LongRunHighGrayLevelEmphasis" 340.000000 ################
#     2.                       "RunEntropy" 152.000000 ######
#     3.     "ShortRunLowGrayLevelEmphasis" 117.000000 ####
#     4.    "ShortRunHighGrayLevelEmphasis" 115.000000 ####
#     5.                "GrayLevelVariance" 113.000000 ####
#     6.         "HighGrayLevelRunEmphasis" 99.000000 ###
#     7. "GrayLevelNonUniformityNormalized" 91.000000 ###
#     8.      "LongRunLowGrayLevelEmphasis" 87.000000 ##
#     9.                      "RunVariance" 70.000000 ##
#    10.           "GrayLevelNonUniformity" 69.000000 ##
#    11.          "LowGrayLevelRunEmphasis" 59.000000 #
#    12. "RunLengthNonUniformityNormalized" 58.000000 #
#    13.                    "RunPercentage" 45.000000
#    14.           "RunLengthNonUniformity" 42.000000
#    15.                  "LongRunEmphasis" 34.000000
#    16.                 "ShortRunEmphasis" 30.000000
#
# Variable Importance: SUM_SCORE:
#     1.     "LongRunHighGrayLevelEmphasis" 5724.053307 ################
#     2.    "ShortRunHighGrayLevelEmphasis" 623.181203 #
#     3.                       "RunEntropy" 328.334988
#     4.     "ShortRunLowGrayLevelEmphasis" 297.741656
#     5. "GrayLevelNonUniformityNormalized" 273.737015
#     6.                "GrayLevelVariance" 267.547925
#     7.      "LongRunLowGrayLevelEmphasis" 177.778232
#     8.         "HighGrayLevelRunEmphasis" 167.760067
#     9.                      "RunVariance" 127.015633
#    10.           "GrayLevelNonUniformity" 117.775078
#    11. "RunLengthNonUniformityNormalized" 97.404936
#    12.                  "LongRunEmphasis" 88.055112
#    13.           "RunLengthNonUniformity" 81.216083
#    14.                    "RunPercentage" 70.378546
#    15.          "LowGrayLevelRunEmphasis" 63.507687
#    16.                 "ShortRunEmphasis" 44.773844
#
#
#
# Loss: BINOMIAL_LOG_LIKELIHOOD
# Validation loss value: 0.326166
# Number of trees per iteration: 1
# Node format: NOT_SET
# Number of trees: 60
# Total number of nodes: 3102
#
# Number of nodes by tree:
# Count: 60 Average: 51.7 StdDev: 6.93614
# Min: 33 Max: 63 Ignored: 0
# ----------------------------------------------
# [ 33, 34)  1   1.67%   1.67% #
# [ 34, 36)  0   0.00%   1.67%
# [ 36, 37)  0   0.00%   1.67%
# [ 37, 39)  2   3.33%   5.00% ##
# [ 39, 40)  1   1.67%   6.67% #
# [ 40, 42)  1   1.67%   8.33% #
# [ 42, 43)  0   0.00%   8.33%
# [ 43, 45)  2   3.33%  11.67% ##
# [ 45, 46)  5   8.33%  20.00% #####
# [ 46, 48)  8  13.33%  33.33% ########
# [ 48, 50)  4   6.67%  40.00% ####
# [ 50, 51)  0   0.00%  40.00%
# [ 51, 53)  6  10.00%  50.00% ######
# [ 53, 54)  3   5.00%  55.00% ###
# [ 54, 56)  6  10.00%  65.00% ######
# [ 56, 57)  0   0.00%  65.00%
# [ 57, 59) 10  16.67%  81.67% ##########
# [ 59, 60)  3   5.00%  86.67% ###
# [ 60, 62)  7  11.67%  98.33% #######
# [ 62, 63]  1   1.67% 100.00% #
#
# Depth by leafs:
# Count: 1581 Average: 4.83618 StdDev: 0.474905
# Min: 2 Max: 5 Ignored: 0
# ----------------------------------------------
# [ 2, 3)   10   0.63%   0.63%
# [ 3, 4)   40   2.53%   3.16%
# [ 4, 5)  149   9.42%  12.59% #
# [ 5, 5] 1382  87.41% 100.00% ##########
#
# Number of training obs by leaf:
# Count: 1581 Average: 260.683 StdDev: 586.274
# Min: 5 Max: 5693 Ignored: 0
# ----------------------------------------------
# [    5,  289) 1259  79.63%  79.63% ##########
# [  289,  573)  117   7.40%  87.03% #
# [  573,  858)   67   4.24%  91.27% #
# [  858, 1142)   32   2.02%  93.30%
# [ 1142, 1427)   28   1.77%  95.07%
# [ 1427, 1711)   14   0.89%  95.95%
# [ 1711, 1996)   18   1.14%  97.09%
# [ 1996, 2280)   12   0.76%  97.85%
# [ 2280, 2565)   13   0.82%  98.67%
# [ 2565, 2849)    5   0.32%  98.99%
# [ 2849, 3133)    2   0.13%  99.11%
# [ 3133, 3418)    2   0.13%  99.24%
# [ 3418, 3702)    3   0.19%  99.43%
# [ 3702, 3987)    4   0.25%  99.68%
# [ 3987, 4271)    1   0.06%  99.75%
# [ 4271, 4556)    1   0.06%  99.81%
# [ 4556, 4840)    2   0.13%  99.94%
# [ 4840, 5125)    0   0.00%  99.94%
# [ 5125, 5409)    0   0.00%  99.94%
# [ 5409, 5693]    1   0.06% 100.00%
#
# Attribute in nodes:
# 	340 : LongRunHighGrayLevelEmphasis [NUMERICAL]
# 	152 : RunEntropy [NUMERICAL]
# 	117 : ShortRunLowGrayLevelEmphasis [NUMERICAL]
# 	115 : ShortRunHighGrayLevelEmphasis [NUMERICAL]
# 	113 : GrayLevelVariance [NUMERICAL]
# 	99 : HighGrayLevelRunEmphasis [NUMERICAL]
# 	91 : GrayLevelNonUniformityNormalized [NUMERICAL]
# 	87 : LongRunLowGrayLevelEmphasis [NUMERICAL]
# 	70 : RunVariance [NUMERICAL]
# 	69 : GrayLevelNonUniformity [NUMERICAL]
# 	59 : LowGrayLevelRunEmphasis [NUMERICAL]
# 	58 : RunLengthNonUniformityNormalized [NUMERICAL]
# 	45 : RunPercentage [NUMERICAL]
# 	42 : RunLengthNonUniformity [NUMERICAL]
# 	34 : LongRunEmphasis [NUMERICAL]
# 	30 : ShortRunEmphasis [NUMERICAL]
#
# Attribute in nodes with depth <= 0:
# 	45 : LongRunHighGrayLevelEmphasis [NUMERICAL]
# 	4 : LongRunLowGrayLevelEmphasis [NUMERICAL]
# 	3 : RunEntropy [NUMERICAL]
# 	3 : HighGrayLevelRunEmphasis [NUMERICAL]
# 	2 : ShortRunLowGrayLevelEmphasis [NUMERICAL]
# 	1 : RunVariance [NUMERICAL]
# 	1 : LowGrayLevelRunEmphasis [NUMERICAL]
# 	1 : GrayLevelNonUniformity [NUMERICAL]
#
# Attribute in nodes with depth <= 1:
# 	86 : LongRunHighGrayLevelEmphasis [NUMERICAL]
# 	16 : ShortRunLowGrayLevelEmphasis [NUMERICAL]
# 	12 : RunEntropy [NUMERICAL]
# 	10 : RunLengthNonUniformityNormalized [NUMERICAL]
# 	10 : LongRunLowGrayLevelEmphasis [NUMERICAL]
# 	10 : HighGrayLevelRunEmphasis [NUMERICAL]
# 	6 : ShortRunHighGrayLevelEmphasis [NUMERICAL]
# 	6 : GrayLevelNonUniformityNormalized [NUMERICAL]
# 	5 : LowGrayLevelRunEmphasis [NUMERICAL]
# 	5 : GrayLevelNonUniformity [NUMERICAL]
# 	4 : GrayLevelVariance [NUMERICAL]
# 	3 : RunVariance [NUMERICAL]
# 	3 : RunLengthNonUniformity [NUMERICAL]
# 	2 : RunPercentage [NUMERICAL]
# 	1 : ShortRunEmphasis [NUMERICAL]
# 	1 : LongRunEmphasis [NUMERICAL]
#
# Attribute in nodes with depth <= 2:
# 	119 : LongRunHighGrayLevelEmphasis [NUMERICAL]
# 	37 : RunEntropy [NUMERICAL]
# 	32 : ShortRunLowGrayLevelEmphasis [NUMERICAL]
# 	28 : ShortRunHighGrayLevelEmphasis [NUMERICAL]
# 	28 : LongRunLowGrayLevelEmphasis [NUMERICAL]
# 	27 : HighGrayLevelRunEmphasis [NUMERICAL]
# 	20 : RunPercentage [NUMERICAL]
# 	20 : RunLengthNonUniformityNormalized [NUMERICAL]
# 	17 : RunLengthNonUniformity [NUMERICAL]
# 	17 : GrayLevelNonUniformityNormalized [NUMERICAL]
# 	14 : RunVariance [NUMERICAL]
# 	14 : GrayLevelVariance [NUMERICAL]
# 	13 : LowGrayLevelRunEmphasis [NUMERICAL]
# 	11 : GrayLevelNonUniformity [NUMERICAL]
# 	7 : ShortRunEmphasis [NUMERICAL]
# 	6 : LongRunEmphasis [NUMERICAL]
#
# Attribute in nodes with depth <= 3:
# 	211 : LongRunHighGrayLevelEmphasis [NUMERICAL]
# 	86 : RunEntropy [NUMERICAL]
# 	61 : ShortRunLowGrayLevelEmphasis [NUMERICAL]
# 	58 : ShortRunHighGrayLevelEmphasis [NUMERICAL]
# 	56 : HighGrayLevelRunEmphasis [NUMERICAL]
# 	55 : GrayLevelNonUniformityNormalized [NUMERICAL]
# 	49 : LongRunLowGrayLevelEmphasis [NUMERICAL]
# 	43 : GrayLevelVariance [NUMERICAL]
# 	33 : GrayLevelNonUniformity [NUMERICAL]
# 	32 : LowGrayLevelRunEmphasis [NUMERICAL]
# 	31 : RunLengthNonUniformityNormalized [NUMERICAL]
# 	30 : RunVariance [NUMERICAL]
# 	28 : RunPercentage [NUMERICAL]
# 	27 : RunLengthNonUniformity [NUMERICAL]
# 	16 : ShortRunEmphasis [NUMERICAL]
# 	14 : LongRunEmphasis [NUMERICAL]
#
# Attribute in nodes with depth <= 5:
# 	340 : LongRunHighGrayLevelEmphasis [NUMERICAL]
# 	152 : RunEntropy [NUMERICAL]
# 	117 : ShortRunLowGrayLevelEmphasis [NUMERICAL]
# 	115 : ShortRunHighGrayLevelEmphasis [NUMERICAL]
# 	113 : GrayLevelVariance [NUMERICAL]
# 	99 : HighGrayLevelRunEmphasis [NUMERICAL]
# 	91 : GrayLevelNonUniformityNormalized [NUMERICAL]
# 	87 : LongRunLowGrayLevelEmphasis [NUMERICAL]
# 	70 : RunVariance [NUMERICAL]
# 	69 : GrayLevelNonUniformity [NUMERICAL]
# 	59 : LowGrayLevelRunEmphasis [NUMERICAL]
# 	58 : RunLengthNonUniformityNormalized [NUMERICAL]
# 	45 : RunPercentage [NUMERICAL]
# 	42 : RunLengthNonUniformity [NUMERICAL]
# 	34 : LongRunEmphasis [NUMERICAL]
# 	30 : ShortRunEmphasis [NUMERICAL]
#
# Condition type in nodes:
# 	1521 : HigherCondition
# Condition type in nodes with depth <= 0:
# 	60 : HigherCondition
# Condition type in nodes with depth <= 1:
# 	180 : HigherCondition
# Condition type in nodes with depth <= 2:
# 	410 : HigherCondition
# Condition type in nodes with depth <= 3:
# 	830 : HigherCondition
# Condition type in nodes with depth <= 5:
# 	1521 : HigherCondition
#
# Training logs:
# Number of iteration to final model: 60
# 	Iter:1 train-loss:1.249916 valid-loss:1.247922  train-accuracy:0.904964 valid-accuracy:0.915813
# 	Iter:2 train-loss:1.137624 valid-loss:1.134567  train-accuracy:0.904999 valid-accuracy:0.906188
# 	Iter:3 train-loss:1.042952 valid-loss:1.036033  train-accuracy:0.905237 valid-accuracy:0.915813
# 	Iter:4 train-loss:0.962595 valid-loss:0.955164  train-accuracy:0.906438 valid-accuracy:0.917347
# 	Iter:5 train-loss:0.892538 valid-loss:0.887085  train-accuracy:0.914412 valid-accuracy:0.914278
# 	Iter:6 train-loss:0.832712 valid-loss:0.831040  train-accuracy:0.910116 valid-accuracy:0.914278
# 	Iter:16 train-loss:0.472292 valid-loss:0.500983  train-accuracy:0.949060 valid-accuracy:0.920416
# 	Iter:26 train-loss:0.337224 valid-loss:0.396057  train-accuracy:0.960438 valid-accuracy:0.911559
# 	Iter:36 train-loss:0.269727 valid-loss:0.357332  train-accuracy:0.970230 valid-accuracy:0.912326
# 	Iter:46 train-loss:0.223206 valid-loss:0.344141  train-accuracy:0.975649 valid-accuracy:0.913093
# 	Iter:56 train-loss:0.191957 valid-loss:0.331474  train-accuracy:0.981532 valid-accuracy:0.915395
# 	Iter:66 train-loss:0.167627 valid-loss:0.340248  train-accuracy:0.986368 valid-accuracy:0.915395
# 	Iter:76 train-loss:0.146914 valid-loss:0.339577  train-accuracy:0.987449 valid-accuracy:0.915395
# 	Iter:86 train-loss:0.131617 valid-loss:0.342130  train-accuracy:0.988839 valid-accuracy:0.915395

# %%
# Model features
model.make_inspector().features()
# Out:
# ["GrayLevelNonUniformity" (1; #0),
#  "GrayLevelNonUniformityNormalized" (1; #1),
#  "GrayLevelVariance" (1; #2),
#  "HighGrayLevelRunEmphasis" (1; #3),
#  "LongRunEmphasis" (1; #4),
#  "LongRunHighGrayLevelEmphasis" (1; #5),
#  "LongRunLowGrayLevelEmphasis" (1; #6),
#  "LowGrayLevelRunEmphasis" (1; #7),
#  "RunEntropy" (1; #8),
#  "RunLengthNonUniformity" (1; #9),
#  "RunLengthNonUniformityNormalized" (1; #10),
#  "RunPercentage" (1; #11),
#  "RunVariance" (1; #12),
#  "ShortRunEmphasis" (1; #13),
#  "ShortRunHighGrayLevelEmphasis" (1; #14),
#  "ShortRunLowGrayLevelEmphasis" (1; #15)]

# %%
# Feature importance
model.make_inspector().variable_importances()
# Out:
# {'INV_MEAN_MIN_DEPTH': [("LongRunHighGrayLevelEmphasis" (1; #5),
#    0.5038843221562727),
#   ("RunEntropy" (1; #8), 0.2112140280263141),
#   ("ShortRunLowGrayLevelEmphasis" (1; #15), 0.1997265267823311),
#   ("HighGrayLevelRunEmphasis" (1; #3), 0.1979893009847048),
#   ("LongRunLowGrayLevelEmphasis" (1; #6), 0.19612498561129385),
#   ("ShortRunHighGrayLevelEmphasis" (1; #14), 0.1920298718413564),
#   ("RunLengthNonUniformityNormalized" (1; #10), 0.1902773036145445),
#   ("GrayLevelNonUniformityNormalized" (1; #1), 0.18698393707577282),
#   ("GrayLevelVariance" (1; #2), 0.18568813105816262),
#   ("GrayLevelNonUniformity" (1; #0), 0.18360423885599544),
#   ("RunVariance" (1; #12), 0.18352056851517135),
#   ("LowGrayLevelRunEmphasis" (1; #7), 0.1834279350460185),
#   ("RunLengthNonUniformity" (1; #9), 0.18167145157224845),
#   ("RunPercentage" (1; #11), 0.1809319838139922),
#   ("ShortRunEmphasis" (1; #13), 0.1762288663388346),
#   ("LongRunEmphasis" (1; #4), 0.17601857412986197)],
#  'NUM_AS_ROOT': [("LongRunHighGrayLevelEmphasis" (1; #5), 45.0),
#   ("LongRunLowGrayLevelEmphasis" (1; #6), 4.0),
#   ("HighGrayLevelRunEmphasis" (1; #3), 3.0),
#   ("RunEntropy" (1; #8), 3.0),
#   ("ShortRunLowGrayLevelEmphasis" (1; #15), 2.0),
#   ("GrayLevelNonUniformity" (1; #0), 1.0),
#   ("LowGrayLevelRunEmphasis" (1; #7), 1.0),
#   ("RunVariance" (1; #12), 1.0)],
#  'SUM_SCORE': [("LongRunHighGrayLevelEmphasis" (1; #5), 5724.053306602858),
#   ("ShortRunHighGrayLevelEmphasis" (1; #14), 623.1812028085378),
#   ("RunEntropy" (1; #8), 328.3349878771612),
#   ("ShortRunLowGrayLevelEmphasis" (1; #15), 297.74165565237735),
#   ("GrayLevelNonUniformityNormalized" (1; #1), 273.73701535095887),
#   ("GrayLevelVariance" (1; #2), 267.5479251666459),
#   ("LongRunLowGrayLevelEmphasis" (1; #6), 177.77823190641638),
#   ("HighGrayLevelRunEmphasis" (1; #3), 167.7600666275669),
#   ("RunVariance" (1; #12), 127.01563288087291),
#   ("GrayLevelNonUniformity" (1; #0), 117.77507809352348),
#   ("RunLengthNonUniformityNormalized" (1; #10), 97.40493597712141),
#   ("LongRunEmphasis" (1; #4), 88.05511171030085),
#   ("RunLengthNonUniformity" (1; #9), 81.21608276618277),
#   ("RunPercentage" (1; #11), 70.37854574846816),
#   ("LowGrayLevelRunEmphasis" (1; #7), 63.507687336267026),
#   ("ShortRunEmphasis" (1; #13), 44.77384363161518)],
#  'NUM_NODES': [("LongRunHighGrayLevelEmphasis" (1; #5), 340.0),
#   ("RunEntropy" (1; #8), 152.0),
#   ("ShortRunLowGrayLevelEmphasis" (1; #15), 117.0),
#   ("ShortRunHighGrayLevelEmphasis" (1; #14), 115.0),
#   ("GrayLevelVariance" (1; #2), 113.0),
#   ("HighGrayLevelRunEmphasis" (1; #3), 99.0),
#   ("GrayLevelNonUniformityNormalized" (1; #1), 91.0),
#   ("LongRunLowGrayLevelEmphasis" (1; #6), 87.0),
#   ("RunVariance" (1; #12), 70.0),
#   ("GrayLevelNonUniformity" (1; #0), 69.0),
#   ("LowGrayLevelRunEmphasis" (1; #7), 59.0),
#   ("RunLengthNonUniformityNormalized" (1; #10), 58.0),
#   ("RunPercentage" (1; #11), 45.0),
#   ("RunLengthNonUniformity" (1; #9), 42.0),
#   ("LongRunEmphasis" (1; #4), 34.0),
#   ("ShortRunEmphasis" (1; #13), 30.0)]}

# %%
# Model self evaluation
model.make_inspector().evaluation()
# Out:
# Evaluation(num_examples=None, accuracy=0.9153948426246643, loss=0.3261657953262329, rmse=None, ndcg=None, aucs=None, auuc=None, qini=None)

# %%
logs = model.make_inspector().training_logs()

plt.figure(figsize=(12, 4))
plt.subplot(1, 2, 1)
plt.plot([log.num_trees for log in logs], [log.evaluation.accuracy for log in logs])
plt.xlabel("Number of trees")
plt.ylabel("Accuracy (out-of-bag)")
plt.subplot(1, 2, 2)
plt.plot([log.num_trees for log in logs], [log.evaluation.loss for log in logs])
plt.xlabel("Number of trees")
plt.ylabel("Logloss (out-of-bag)")
plt.show()

# %% [markdown]
# Calculate the score of our hold-out validation dataset

# %%
predictions = model.predict(val_ds)
y_true      = validation_data["label"]

from sklearn.metrics import roc_auc_score
ROC_AUC = roc_auc_score(y_true, predictions)
print("The ROC AUC score is %.5f" % ROC_AUC )
# Out:
# 1/2 [==============>...............] - ETA: 0s
# 2/2 [==============================] - 0s 2ms/step
# The ROC AUC score is 0.99791

# %%
# Compute binary classification metrics with sklearn
import numpy as np
from sklearn.metrics import (
    accuracy_score,
    precision_score,
    recall_score,
    f1_score,
    roc_auc_score,
    average_precision_score,
    confusion_matrix,
    classification_report,
    matthews_corrcoef,
    log_loss,
    brier_score_loss,
)

# Get predictions (probabilities or class labels)
preds = model.predict(test_ds)
# If model outputs probabilities, convert to labels by threshold 0.5
if preds.ndim == 2:
    # For TFDF classification, preds may be class probabilities with shape (N, 2)
    if preds.shape[1] == 2:
        pos_probs = preds[:, 1]
    else:
        # If single-probability column (positive class)
        pos_probs = preds[:, -1]
    y_pred = (pos_probs >= 0.5).astype(int)
else:
    # Already class labels
    y_pred = preds.astype(int)
    pos_probs = None

# Ground truth labels (must be 0/1 integers)
y_true = test_data["label"].astype(int).to_numpy()

# Core metrics
metrics = {}
metrics["accuracy"] = accuracy_score(y_true, y_pred)
metrics["precision"] = precision_score(y_true, y_pred, zero_division=0)
metrics["recall"] = recall_score(y_true, y_pred, zero_division=0)
metrics["f1"] = f1_score(y_true, y_pred, zero_division=0)
metrics["mcc"] = matthews_corrcoef(y_true, y_pred)

# Probabilistic metrics (only if we have probabilities)
if pos_probs is not None:
    metrics["roc_auc"] = roc_auc_score(y_true, pos_probs)
    metrics["pr_auc"] = average_precision_score(y_true, pos_probs)
    metrics["log_loss"] = log_loss(y_true, pos_probs, labels=[0,1])
    metrics["brier_score"] = brier_score_loss(y_true, pos_probs)

# Confusion matrix and detailed report
cm = confusion_matrix(y_true, y_pred, labels=[0,1])
report = classification_report(y_true, y_pred, digits=4)

print("Sklearn binary metrics:")
for k, v in metrics.items():
    print(f"{k}: {v:.4f}")
print("\nConfusion matrix:\n", cm)
print("\nClassification report:\n", report)
# Out:
# 1/3 [=========>....................] - ETA: 0s
# 3/3 [==============================] - 0s 3ms/step
# Sklearn binary metrics:
# accuracy: 0.9628
# precision: 0.8008
# recall: 0.8326
# f1: 0.8164
# mcc: 0.7959
# roc_auc: 0.9578
# pr_auc: 0.8744
# log_loss: 0.1205
# brier_score: 0.0300
#
# Confusion matrix:
#  [[2009   47]
#  [  38  189]]
#
# Classification report:
#                precision    recall  f1-score   support
#
#            0     0.9814    0.9771    0.9793      2056
#            1     0.8008    0.8326    0.8164       227
#
#     accuracy                         0.9628      2283
#    macro avg     0.8911    0.9049    0.8978      2283
# weighted avg     0.9635    0.9628    0.9631      2283
