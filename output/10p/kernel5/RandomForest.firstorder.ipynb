# %%
# Import packages and modules
import numpy  as np
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow_decision_forests as tfdf

from sklearn.model_selection import train_test_split
# Out:
# 2026-09-11 08:23:18.728131: I tensorflow/core/util/port.cc:113] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2026-09-11 08:23:18.768096: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2026-09-11 08:23:23.047621: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
# Check the version of TensorFlow Decision Forests
print("Found TensorFlow Decision Forests v" + tfdf.__version__)
# Out:
# Found TensorFlow Decision Forests v1.9.1

# %%
datasetPath = "dataset/10p/all/kernel3/"

# %%
# Parameters
datasetPath = "dataset/10p/firstorder/kernel5/"

# %%
# train/validation/test = 70/10/20
train_data = pd.read_csv(f"{datasetPath}dataset.train.csv")
validation_data = pd.read_csv(f"{datasetPath}dataset.validation.csv")
test_data = pd.read_csv(f"{datasetPath}dataset.test.csv")

# %%
from sklearn.utils.class_weight import compute_class_weight

# tinh class weight tren tap train
classes = np.array([0, 1])
weights = compute_class_weight(class_weight="balanced", classes=classes, y=train_data["label"])
class_weight = {0: weights[0], 1: weights[1]}

# gan sample_weight cho tung dong
train_data["sample_weight"] = train_data["label"].map(class_weight)
validation_data["sample_weight"] = validation_data["label"].map(class_weight)
test_data["sample_weight"] = test_data["label"].map(class_weight)

# Convert the dataset into a TensorFlow dataset.
train_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    train_data, label="label", weight="sample_weight"
)         
val_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    validation_data, label="label", weight="sample_weight"
)
test_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    test_data, label="label", weight="sample_weight"
)
# Out:
# 2026-09-11 08:23:34.920641: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:984] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2026-09-11 08:23:34.922266: W tensorflow/core/common_runtime/gpu/gpu_device.cc:2251] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...

# %%
import keras

# %%
# %%time

# Train a Random Forest model.
model = tfdf.keras.RandomForestModel()

# Add evaluation metrics
model.compile(
    metrics=["accuracy"]
)
model.fit(x=train_ds)

# # Train a Gradient Boosted Trees model.
# model = tfdf.keras.GradientBoostedTreesModel(num_trees=1500)
# model.fit(train_ds)
# Out:
# Use /tmp/tmp_dd87xzs as temporary training directory
# Reading training dataset...
# Training dataset read in 0:00:02.503013. Found 7617 examples.
# Training model...
# Model trained in 0:00:00.564632
# Compiling model...
# [INFO 26-09-11 08:23:38.0342 UTC kernel.cc:1233] Loading model from path /tmp/tmp_dd87xzs/model/ with prefix 9f734c461b5a4a82
# [INFO 26-09-11 08:23:38.1256 UTC decision_forest.cc:734] Model loaded with 300 root(s), 80034 node(s), and 18 input feature(s).
# [INFO 26-09-11 08:23:38.1256 UTC abstract_model.cc:1362] Engine "RandomForestOptPred" built
# [INFO 26-09-11 08:23:38.1256 UTC kernel.cc:1061] Use fast generic engine
# Model compiled.
# CPU times: user 9.95 s, sys: 147 ms, total: 10.1 s
# Wall time: 6.12 s

# %%
# Evaluate the model
evaluate = model.evaluate(val_ds, return_dict=True)
print()

for name, value in evaluate.items():
    print(f"{name}: {value:.4f}")
# Out:
# WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 1/2 [==============>...............] - ETA: 4s - loss: 0.0000e+00 - accuracy: 0.9880
# 2/2 [==============================] - 4s 8ms/step - loss: 0.0000e+00 - accuracy: 0.9888
# loss: 0.0000
# accuracy: 0.9888

# %%
# Model Summary
model.summary()
# Out:
# Model: "random_forest_model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
# =================================================================
# Total params: 1 (1.00 Byte)
# Trainable params: 0 (0.00 Byte)
# Non-trainable params: 1 (1.00 Byte)
# _________________________________________________________________
# Type: "RANDOM_FOREST"
# Task: CLASSIFICATION
# Label: "__LABEL"
#
# Input Features (18):
# 	10Percentile
# 	90Percentile
# 	Energy
# 	Entropy
# 	InterquartileRange
# 	Kurtosis
# 	Maximum
# 	Mean
# 	MeanAbsoluteDeviation
# 	Median
# 	Minimum
# 	Range
# 	RobustMeanAbsoluteDeviation
# 	RootMeanSquared
# 	Skewness
# 	TotalEnergy
# 	Uniformity
# 	Variance
#
# Trained with weights
#
# Variable Importance: INV_MEAN_MIN_DEPTH:
#     1.                      "Median"  0.172100 ################
#     2.                "90Percentile"  0.167177 ##############
#     3.                        "Mean"  0.144421 #########
#     4.                      "Energy"  0.143379 #########
#     5.                     "Maximum"  0.143200 #########
#     6.                 "TotalEnergy"  0.141501 ########
#     7.             "RootMeanSquared"  0.137543 #######
#     8.                  "Uniformity"  0.121213 ###
#     9.                    "Skewness"  0.115905 ##
#    10.                "10Percentile"  0.113533 ##
#    11.                     "Entropy"  0.113170 ##
#    12.          "InterquartileRange"  0.111901 #
#    13.                       "Range"  0.109704 #
#    14.                    "Kurtosis"  0.109329 #
#    15.                    "Variance"  0.108499
#    16. "RobustMeanAbsoluteDeviation"  0.107074
#    17.       "MeanAbsoluteDeviation"  0.105722
#    18.                     "Minimum"  0.104424
#
# Variable Importance: NUM_AS_ROOT:
#     1.    "90Percentile" 64.000000 ################
#     2.          "Energy" 60.000000 ##############
#     3.     "TotalEnergy" 59.000000 ##############
#     4. "RootMeanSquared" 51.000000 ############
#     5.            "Mean" 38.000000 #########
#     6.         "Maximum" 12.000000 ##
#     7.          "Median"  9.000000 ##
#     8.    "10Percentile"  4.000000
#     9.         "Minimum"  2.000000
#    10.      "Uniformity"  1.000000
#
# Variable Importance: NUM_NODES:
#     1.                    "Skewness" 3111.000000 ################
#     2.                     "Maximum" 3038.000000 ###############
#     3.                      "Median" 2832.000000 #############
#     4.                  "Uniformity" 2578.000000 ##########
#     5.                "90Percentile" 2543.000000 #########
#     6.                    "Kurtosis" 2534.000000 #########
#     7.                       "Range" 2450.000000 ########
#     8.                     "Entropy" 2201.000000 ######
#     9.                    "Variance" 2086.000000 #####
#    10.                        "Mean" 2007.000000 ####
#    11.          "InterquartileRange" 1966.000000 ###
#    12.                "10Percentile" 1948.000000 ###
#    13.                     "Minimum" 1935.000000 ###
#    14. "RobustMeanAbsoluteDeviation" 1902.000000 ###
#    15.       "MeanAbsoluteDeviation" 1816.000000 ##
#    16.                      "Energy" 1676.000000
#    17.                 "TotalEnergy" 1641.000000
#    18.             "RootMeanSquared" 1603.000000
#
# Variable Importance: SUM_SCORE:
#     1.                "90Percentile" 203909.218946 ################
#     2.                      "Energy" 168285.877383 ############
#     3.                 "TotalEnergy" 165539.408889 ############
#     4.             "RootMeanSquared" 144216.335192 ##########
#     5.                        "Mean" 134951.949890 #########
#     6.                      "Median" 109788.540314 #######
#     7.                     "Maximum" 97849.695898 ######
#     8.                  "Uniformity" 55801.294431 ##
#     9.                    "Skewness" 55220.794447 ##
#    10.                "10Percentile" 44873.618366 #
#    11.                     "Entropy" 44313.101062 #
#    12.                    "Kurtosis" 42648.617511 #
#    13.                       "Range" 42275.985832 #
#    14.          "InterquartileRange" 38336.380662
#    15.                    "Variance" 35891.939947
#    16. "RobustMeanAbsoluteDeviation" 34776.441638
#    17.       "MeanAbsoluteDeviation" 31086.291440
#    18.                     "Minimum" 29863.286953
#
#
#
# Winner takes all: true
# Out-of-bag evaluation: accuracy:0.824336 logloss:0.763426
# Number of trees: 300
# Total number of nodes: 80034
#
# Number of nodes by tree:
# Count: 300 Average: 266.78 StdDev: 17.1594
# Min: 209 Max: 313 Ignored: 0
# ----------------------------------------------
# [ 209, 214)  1   0.33%   0.33%
# [ 214, 219)  0   0.00%   0.33%
# [ 219, 224)  2   0.67%   1.00%
# [ 224, 230)  3   1.00%   2.00% #
# [ 230, 235)  5   1.67%   3.67% #
# [ 235, 240)  9   3.00%   6.67% ##
# [ 240, 245) 10   3.33%  10.00% ##
# [ 245, 251) 20   6.67%  16.67% ####
# [ 251, 256) 24   8.00%  24.67% #####
# [ 256, 261) 23   7.67%  32.33% #####
# [ 261, 266) 48  16.00%  48.33% ##########
# [ 266, 272) 40  13.33%  61.67% ########
# [ 272, 277) 27   9.00%  70.67% ######
# [ 277, 282) 32  10.67%  81.33% #######
# [ 282, 287) 15   5.00%  86.33% ###
# [ 287, 293) 17   5.67%  92.00% ####
# [ 293, 298) 17   5.67%  97.67% ####
# [ 298, 303)  3   1.00%  98.67% #
# [ 303, 308)  3   1.00%  99.67% #
# [ 308, 313]  1   0.33% 100.00%
#
# Depth by leafs:
# Count: 40167 Average: 9.74857 StdDev: 2.89994
# Min: 2 Max: 15 Ignored: 0
# ----------------------------------------------
# [  2,  3)  123   0.31%   0.31%
# [  3,  4)  499   1.24%   1.55% #
# [  4,  5)  865   2.15%   3.70% ##
# [  5,  6) 1566   3.90%   7.60% ###
# [  6,  7) 2522   6.28%  13.88% #####
# [  7,  8) 3586   8.93%  22.81% #######
# [  8,  9) 4560  11.35%  34.16% #########
# [  9, 10) 4974  12.38%  46.54% ##########
# [ 10, 11) 5229  13.02%  59.56% ##########
# [ 11, 12) 4641  11.55%  71.12% #########
# [ 12, 13) 3980   9.91%  81.02% ########
# [ 13, 14) 3061   7.62%  88.64% ######
# [ 14, 15) 2251   5.60%  94.25% ####
# [ 15, 15] 2310   5.75% 100.00% ####
#
# Number of training obs by leaf:
# Count: 40167 Average: 56.89 StdDev: 160.12
# Min: 5 Max: 1726 Ignored: 0
# ----------------------------------------------
# [    5,   91) 35167  87.55%  87.55% ##########
# [   91,  177)  1832   4.56%  92.11% #
# [  177,  263)  1015   2.53%  94.64%
# [  263,  349)   521   1.30%  95.94%
# [  349,  435)   405   1.01%  96.95%
# [  435,  521)   245   0.61%  97.56%
# [  521,  607)   184   0.46%  98.01%
# [  607,  693)   157   0.39%  98.40%
# [  693,  779)   101   0.25%  98.66%
# [  779,  866)    76   0.19%  98.84%
# [  866,  952)    64   0.16%  99.00%
# [  952, 1038)   106   0.26%  99.27%
# [ 1038, 1124)    38   0.09%  99.36%
# [ 1124, 1210)    43   0.11%  99.47%
# [ 1210, 1296)    35   0.09%  99.56%
# [ 1296, 1382)    82   0.20%  99.76%
# [ 1382, 1468)    67   0.17%  99.93%
# [ 1468, 1554)    14   0.03%  99.96%
# [ 1554, 1640)    11   0.03%  99.99%
# [ 1640, 1726]     4   0.01% 100.00%
#
# Attribute in nodes:
# 	3111 : Skewness [NUMERICAL]
# 	3038 : Maximum [NUMERICAL]
# 	2832 : Median [NUMERICAL]
# 	2578 : Uniformity [NUMERICAL]
# 	2543 : 90Percentile [NUMERICAL]
# 	2534 : Kurtosis [NUMERICAL]
# 	2450 : Range [NUMERICAL]
# 	2201 : Entropy [NUMERICAL]
# 	2086 : Variance [NUMERICAL]
# 	2007 : Mean [NUMERICAL]
# 	1966 : InterquartileRange [NUMERICAL]
# 	1948 : 10Percentile [NUMERICAL]
# 	1935 : Minimum [NUMERICAL]
# 	1902 : RobustMeanAbsoluteDeviation [NUMERICAL]
# 	1816 : MeanAbsoluteDeviation [NUMERICAL]
# 	1676 : Energy [NUMERICAL]
# 	1641 : TotalEnergy [NUMERICAL]
# 	1603 : RootMeanSquared [NUMERICAL]
#
# Attribute in nodes with depth <= 0:
# 	64 : 90Percentile [NUMERICAL]
# 	60 : Energy [NUMERICAL]
# 	59 : TotalEnergy [NUMERICAL]
# 	51 : RootMeanSquared [NUMERICAL]
# 	38 : Mean [NUMERICAL]
# 	12 : Maximum [NUMERICAL]
# 	9 : Median [NUMERICAL]
# 	4 : 10Percentile [NUMERICAL]
# 	2 : Minimum [NUMERICAL]
# 	1 : Uniformity [NUMERICAL]
#
# Attribute in nodes with depth <= 1:
# 	180 : Median [NUMERICAL]
# 	159 : Mean [NUMERICAL]
# 	144 : TotalEnergy [NUMERICAL]
# 	123 : Energy [NUMERICAL]
# 	111 : RootMeanSquared [NUMERICAL]
# 	97 : 90Percentile [NUMERICAL]
# 	38 : Maximum [NUMERICAL]
# 	34 : 10Percentile [NUMERICAL]
# 	6 : Minimum [NUMERICAL]
# 	2 : Uniformity [NUMERICAL]
# 	2 : MeanAbsoluteDeviation [NUMERICAL]
# 	1 : Variance [NUMERICAL]
# 	1 : Skewness [NUMERICAL]
# 	1 : Range [NUMERICAL]
# 	1 : Kurtosis [NUMERICAL]
#
# Attribute in nodes with depth <= 2:
# 	350 : Median [NUMERICAL]
# 	268 : Mean [NUMERICAL]
# 	205 : TotalEnergy [NUMERICAL]
# 	191 : Energy [NUMERICAL]
# 	160 : RootMeanSquared [NUMERICAL]
# 	156 : 90Percentile [NUMERICAL]
# 	131 : Skewness [NUMERICAL]
# 	102 : Maximum [NUMERICAL]
# 	80 : Uniformity [NUMERICAL]
# 	68 : 10Percentile [NUMERICAL]
# 	50 : Kurtosis [NUMERICAL]
# 	43 : Minimum [NUMERICAL]
# 	42 : Entropy [NUMERICAL]
# 	38 : InterquartileRange [NUMERICAL]
# 	30 : Variance [NUMERICAL]
# 	26 : RobustMeanAbsoluteDeviation [NUMERICAL]
# 	22 : Range [NUMERICAL]
# 	15 : MeanAbsoluteDeviation [NUMERICAL]
#
# Attribute in nodes with depth <= 3:
# 	488 : Median [NUMERICAL]
# 	362 : Mean [NUMERICAL]
# 	318 : Skewness [NUMERICAL]
# 	294 : Maximum [NUMERICAL]
# 	291 : 90Percentile [NUMERICAL]
# 	274 : TotalEnergy [NUMERICAL]
# 	263 : Energy [NUMERICAL]
# 	234 : RootMeanSquared [NUMERICAL]
# 	176 : Uniformity [NUMERICAL]
# 	142 : Kurtosis [NUMERICAL]
# 	137 : 10Percentile [NUMERICAL]
# 	114 : Entropy [NUMERICAL]
# 	113 : Range [NUMERICAL]
# 	113 : Minimum [NUMERICAL]
# 	91 : Variance [NUMERICAL]
# 	90 : InterquartileRange [NUMERICAL]
# 	76 : RobustMeanAbsoluteDeviation [NUMERICAL]
# 	56 : MeanAbsoluteDeviation [NUMERICAL]
#
# Attribute in nodes with depth <= 5:
# 	917 : Median [NUMERICAL]
# 	880 : Maximum [NUMERICAL]
# 	872 : Skewness [NUMERICAL]
# 	681 : 90Percentile [NUMERICAL]
# 	638 : Mean [NUMERICAL]
# 	558 : Uniformity [NUMERICAL]
# 	508 : TotalEnergy [NUMERICAL]
# 	505 : Kurtosis [NUMERICAL]
# 	454 : RootMeanSquared [NUMERICAL]
# 	452 : Energy [NUMERICAL]
# 	441 : Range [NUMERICAL]
# 	435 : Entropy [NUMERICAL]
# 	413 : 10Percentile [NUMERICAL]
# 	365 : Minimum [NUMERICAL]
# 	360 : InterquartileRange [NUMERICAL]
# 	352 : Variance [NUMERICAL]
# 	302 : MeanAbsoluteDeviation [NUMERICAL]
# 	268 : RobustMeanAbsoluteDeviation [NUMERICAL]
#
# Condition type in nodes:
# 	39867 : HigherCondition
# Condition type in nodes with depth <= 0:
# 	300 : HigherCondition
# Condition type in nodes with depth <= 1:
# 	900 : HigherCondition
# Condition type in nodes with depth <= 2:
# 	1977 : HigherCondition
# Condition type in nodes with depth <= 3:
# 	3632 : HigherCondition
# Condition type in nodes with depth <= 5:
# 	9401 : HigherCondition
# Node format: NOT_SET
#
# Training OOB:
# 	trees: 1, Out-of-bag evaluation: accuracy:0.834707 logloss:5.95775
# 	trees: 12, Out-of-bag evaluation: accuracy:0.81227 logloss:4.07456
# 	trees: 22, Out-of-bag evaluation: accuracy:0.826275 logloss:2.44214
# 	trees: 32, Out-of-bag evaluation: accuracy:0.828986 logloss:1.83703
# 	trees: 42, Out-of-bag evaluation: accuracy:0.826167 logloss:1.57016
# 	trees: 52, Out-of-bag evaluation: accuracy:0.828067 logloss:1.39501
# 	trees: 62, Out-of-bag evaluation: accuracy:0.826097 logloss:1.28826
# 	trees: 72, Out-of-bag evaluation: accuracy:0.825287 logloss:1.2889
# 	trees: 82, Out-of-bag evaluation: accuracy:0.826518 logloss:1.22234
# 	trees: 92, Out-of-bag evaluation: accuracy:0.823316 logloss:1.15066
# 	trees: 102, Out-of-bag evaluation: accuracy:0.824196 logloss:1.08497
# 	trees: 112, Out-of-bag evaluation: accuracy:0.826237 logloss:1.08733
# 	trees: 122, Out-of-bag evaluation: accuracy:0.827257 logloss:1.05492
# 	trees: 132, Out-of-bag evaluation: accuracy:0.829298 logloss:1.02315
# 	trees: 142, Out-of-bag evaluation: accuracy:0.827328 logloss:1.02065
# 	trees: 152, Out-of-bag evaluation: accuracy:0.828418 logloss:0.987902
# 	trees: 162, Out-of-bag evaluation: accuracy:0.830529 logloss:0.922895
# 	trees: 172, Out-of-bag evaluation: accuracy:0.828488 logloss:0.924676
# 	trees: 182, Out-of-bag evaluation: accuracy:0.826447 logloss:0.892938
# 	trees: 192, Out-of-bag evaluation: accuracy:0.825427 logloss:0.892723
# 	trees: 202, Out-of-bag evaluation: accuracy:0.826307 logloss:0.891945
# 	trees: 212, Out-of-bag evaluation: accuracy:0.824407 logloss:0.891522
# 	trees: 222, Out-of-bag evaluation: accuracy:0.824547 logloss:0.828386
# 	trees: 232, Out-of-bag evaluation: accuracy:0.826237 logloss:0.79615
# 	trees: 242, Out-of-bag evaluation: accuracy:0.824336 logloss:0.76387
# 	trees: 252, Out-of-bag evaluation: accuracy:0.824477 logloss:0.764254
# 	trees: 262, Out-of-bag evaluation: accuracy:0.823316 logloss:0.764617
# 	trees: 272, Out-of-bag evaluation: accuracy:0.825497 logloss:0.765333
# 	trees: 282, Out-of-bag evaluation: accuracy:0.825497 logloss:0.765007
# 	trees: 292, Out-of-bag evaluation: accuracy:0.825357 logloss:0.763116
# 	trees: 300, Out-of-bag evaluation: accuracy:0.824336 logloss:0.763426

# %%
# Model features
model.make_inspector().features()
# Out:
# ["10Percentile" (1; #0),
#  "90Percentile" (1; #1),
#  "Energy" (1; #2),
#  "Entropy" (1; #3),
#  "InterquartileRange" (1; #4),
#  "Kurtosis" (1; #5),
#  "Maximum" (1; #6),
#  "Mean" (1; #7),
#  "MeanAbsoluteDeviation" (1; #8),
#  "Median" (1; #9),
#  "Minimum" (1; #10),
#  "Range" (1; #11),
#  "RobustMeanAbsoluteDeviation" (1; #12),
#  "RootMeanSquared" (1; #13),
#  "Skewness" (1; #14),
#  "TotalEnergy" (1; #15),
#  "Uniformity" (1; #16),
#  "Variance" (1; #17)]

# %%
# Feature importance
model.make_inspector().variable_importances()
# Out:
# {'INV_MEAN_MIN_DEPTH': [("Median" (1; #9), 0.17209953481553777),
#   ("90Percentile" (1; #1), 0.16717710970854754),
#   ("Mean" (1; #7), 0.14442140470071943),
#   ("Energy" (1; #2), 0.1433793439241807),
#   ("Maximum" (1; #6), 0.14319998186059274),
#   ("TotalEnergy" (1; #15), 0.14150073062376262),
#   ("RootMeanSquared" (1; #13), 0.137542751772101),
#   ("Uniformity" (1; #16), 0.12121296010813655),
#   ("Skewness" (1; #14), 0.11590527648460228),
#   ("10Percentile" (1; #0), 0.11353326568331111),
#   ("Entropy" (1; #3), 0.11316973151109622),
#   ("InterquartileRange" (1; #4), 0.11190112281871892),
#   ("Range" (1; #11), 0.1097044576210281),
#   ("Kurtosis" (1; #5), 0.10932873874025857),
#   ("Variance" (1; #17), 0.1084992632607309),
#   ("RobustMeanAbsoluteDeviation" (1; #12), 0.10707368721666743),
#   ("MeanAbsoluteDeviation" (1; #8), 0.10572206558597429),
#   ("Minimum" (1; #10), 0.10442393535557282)],
#  'SUM_SCORE': [("90Percentile" (1; #1), 203909.2189459848),
#   ("Energy" (1; #2), 168285.87738336294),
#   ("TotalEnergy" (1; #15), 165539.4088894364),
#   ("RootMeanSquared" (1; #13), 144216.33519185134),
#   ("Mean" (1; #7), 134951.94989046323),
#   ("Median" (1; #9), 109788.5403137108),
#   ("Maximum" (1; #6), 97849.69589764252),
#   ("Uniformity" (1; #16), 55801.294430624555),
#   ("Skewness" (1; #14), 55220.79444665066),
#   ("10Percentile" (1; #0), 44873.61836634595),
#   ("Entropy" (1; #3), 44313.10106225648),
#   ("Kurtosis" (1; #5), 42648.617510507116),
#   ("Range" (1; #11), 42275.985832042694),
#   ("InterquartileRange" (1; #4), 38336.380662318144),
#   ("Variance" (1; #17), 35891.93994747613),
#   ("RobustMeanAbsoluteDeviation" (1; #12), 34776.441637596465),
#   ("MeanAbsoluteDeviation" (1; #8), 31086.2914404124),
#   ("Minimum" (1; #10), 29863.28695254425)],
#  'NUM_AS_ROOT': [("90Percentile" (1; #1), 64.0),
#   ("Energy" (1; #2), 60.0),
#   ("TotalEnergy" (1; #15), 59.0),
#   ("RootMeanSquared" (1; #13), 51.0),
#   ("Mean" (1; #7), 38.0),
#   ("Maximum" (1; #6), 12.0),
#   ("Median" (1; #9), 9.0),
#   ("10Percentile" (1; #0), 4.0),
#   ("Minimum" (1; #10), 2.0),
#   ("Uniformity" (1; #16), 1.0)],
#  'NUM_NODES': [("Skewness" (1; #14), 3111.0),
#   ("Maximum" (1; #6), 3038.0),
#   ("Median" (1; #9), 2832.0),
#   ("Uniformity" (1; #16), 2578.0),
#   ("90Percentile" (1; #1), 2543.0),
#   ("Kurtosis" (1; #5), 2534.0),
#   ("Range" (1; #11), 2450.0),
#   ("Entropy" (1; #3), 2201.0),
#   ("Variance" (1; #17), 2086.0),
#   ("Mean" (1; #7), 2007.0),
#   ("InterquartileRange" (1; #4), 1966.0),
#   ("10Percentile" (1; #0), 1948.0),
#   ("Minimum" (1; #10), 1935.0),
#   ("RobustMeanAbsoluteDeviation" (1; #12), 1902.0),
#   ("MeanAbsoluteDeviation" (1; #8), 1816.0),
#   ("Energy" (1; #2), 1676.0),
#   ("TotalEnergy" (1; #15), 1641.0),
#   ("RootMeanSquared" (1; #13), 1603.0)]}

# %%
# Model self evaluation
model.make_inspector().evaluation()
# Out:
# Evaluation(num_examples=7617, accuracy=0.824336456295446, loss=0.7634257970324475, rmse=None, ndcg=None, aucs=None, auuc=None, qini=None)

# %%
logs = model.make_inspector().training_logs()

plt.figure(figsize=(12, 4))
plt.subplot(1, 2, 1)
plt.plot([log.num_trees for log in logs], [log.evaluation.accuracy for log in logs])
plt.xlabel("Number of trees")
plt.ylabel("Accuracy (out-of-bag)")
plt.subplot(1, 2, 2)
plt.plot([log.num_trees for log in logs], [log.evaluation.loss for log in logs])
plt.xlabel("Number of trees")
plt.ylabel("Logloss (out-of-bag)")
plt.show()

# %% [markdown]
# Calculate the score of our hold-out validation dataset

# %%
predictions = model.predict(val_ds)
y_true      = validation_data["label"]

from sklearn.metrics import roc_auc_score
ROC_AUC = roc_auc_score(y_true, predictions)
print("The ROC AUC score is %.5f" % ROC_AUC )
# Out:
# 1/2 [==============>...............] - ETA: 0s
# 2/2 [==============================] - 0s 4ms/step
# The ROC AUC score is 0.99302

# %%
# Compute binary classification metrics with sklearn
import numpy as np
from sklearn.metrics import (
    accuracy_score,
    precision_score,
    recall_score,
    f1_score,
    roc_auc_score,
    average_precision_score,
    confusion_matrix,
    classification_report,
    matthews_corrcoef,
    log_loss,
    brier_score_loss,
)

# Get predictions (probabilities or class labels)
preds = model.predict(test_ds)
# If model outputs probabilities, convert to labels by threshold 0.5
if preds.ndim == 2:
    # For TFDF classification, preds may be class probabilities with shape (N, 2)
    if preds.shape[1] == 2:
        pos_probs = preds[:, 1]
    else:
        # If single-probability column (positive class)
        pos_probs = preds[:, -1]
    y_pred = (pos_probs >= 0.5).astype(int)
else:
    # Already class labels
    y_pred = preds.astype(int)
    pos_probs = None

# Ground truth labels (must be 0/1 integers)
y_true = test_data["label"].astype(int).to_numpy()

# Core metrics
metrics = {}
metrics["accuracy"] = accuracy_score(y_true, y_pred)
metrics["precision"] = precision_score(y_true, y_pred, zero_division=0)
metrics["recall"] = recall_score(y_true, y_pred, zero_division=0)
metrics["f1"] = f1_score(y_true, y_pred, zero_division=0)
metrics["mcc"] = matthews_corrcoef(y_true, y_pred)

# Probabilistic metrics (only if we have probabilities)
if pos_probs is not None:
    metrics["roc_auc"] = roc_auc_score(y_true, pos_probs)
    metrics["pr_auc"] = average_precision_score(y_true, pos_probs)
    metrics["log_loss"] = log_loss(y_true, pos_probs, labels=[0,1])
    metrics["brier_score"] = brier_score_loss(y_true, pos_probs)

# Confusion matrix and detailed report
cm = confusion_matrix(y_true, y_pred, labels=[0,1])
report = classification_report(y_true, y_pred, digits=4)

print("Sklearn binary metrics:")
for k, v in metrics.items():
    print(f"{k}: {v:.4f}")
print("\nConfusion matrix:\n", cm)
print("\nClassification report:\n", report)
# Out:
# 1/3 [=========>....................] - ETA: 0s
# 3/3 [==============================] - 0s 11ms/step
# Sklearn binary metrics:
# accuracy: 0.9663
# precision: 0.8606
# recall: 0.7885
# f1: 0.8230
# mcc: 0.8053
# roc_auc: 0.9544
# pr_auc: 0.8749
# log_loss: 0.1230
# brier_score: 0.0272
#
# Confusion matrix:
#  [[2027   29]
#  [  48  179]]
#
# Classification report:
#                precision    recall  f1-score   support
#
#            0     0.9769    0.9859    0.9814      2056
#            1     0.8606    0.7885    0.8230       227
#
#     accuracy                         0.9663      2283
#    macro avg     0.9187    0.8872    0.9022      2283
# weighted avg     0.9653    0.9663    0.9656      2283
