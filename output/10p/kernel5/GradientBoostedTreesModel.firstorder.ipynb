# %%
# Import packages and modules
import numpy  as np
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow_decision_forests as tfdf

from sklearn.model_selection import train_test_split
# Out:
# 2026-09-11 08:15:11.754852: I tensorflow/core/util/port.cc:113] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2026-09-11 08:15:11.794871: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2026-09-11 08:15:16.222622: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
# Check the version of TensorFlow Decision Forests
print("Found TensorFlow Decision Forests v" + tfdf.__version__)
# Out:
# Found TensorFlow Decision Forests v1.9.1

# %%
datasetPath = "dataset/10p/all/kernel3/"

# %%
# Parameters
datasetPath = "dataset/10p/firstorder/kernel5/"

# %%
# train/validation/test = 70/10/20
train_data = pd.read_csv(f"{datasetPath}dataset.train.csv")
validation_data = pd.read_csv(f"{datasetPath}dataset.validation.csv")
test_data = pd.read_csv(f"{datasetPath}dataset.test.csv")

# %%
from sklearn.utils.class_weight import compute_class_weight

# tinh class weight tren tap train
classes = np.array([0, 1])
weights = compute_class_weight(class_weight="balanced", classes=classes, y=train_data["label"])
class_weight = {0: weights[0], 1: weights[1]}

# gan sample_weight cho tung dong
train_data["sample_weight"] = train_data["label"].map(class_weight)
validation_data["sample_weight"] = validation_data["label"].map(class_weight)
test_data["sample_weight"] = test_data["label"].map(class_weight)

# Convert the dataset into a TensorFlow dataset.
train_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    train_data, label="label", weight="sample_weight"
)         
val_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    validation_data, label="label", weight="sample_weight"
)
test_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    test_data, label="label", weight="sample_weight"
)
# Out:
# 2026-09-11 08:15:29.491828: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:984] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2026-09-11 08:15:29.493354: W tensorflow/core/common_runtime/gpu/gpu_device.cc:2251] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...

# %%
import keras

# %%
# %%time

# Train a Gradient Boosted Trees model.
model = tfdf.keras.GradientBoostedTreesModel()

# Add evaluation metrics
model.compile(
    metrics=["accuracy"]
)
model.fit(x=train_ds)

# # Train a Gradient Boosted Trees model.
# model = tfdf.keras.GradientBoostedTreesModel(num_trees=1500)
# model.fit(train_ds)
# Out:
# Use /tmp/tmppd0g6vhz as temporary training directory
# Reading training dataset...
# [WARNING 26-09-11 08:15:29.6194 UTC gradient_boosted_trees.cc:1840] "goss_alpha" set but "sampling_method" not equal to "GOSS".
# [WARNING 26-09-11 08:15:29.6195 UTC gradient_boosted_trees.cc:1851] "goss_beta" set but "sampling_method" not equal to "GOSS".
# [WARNING 26-09-11 08:15:29.6195 UTC gradient_boosted_trees.cc:1865] "selective_gradient_boosting_ratio" set but "sampling_method" not equal to "SELGB".
# Training dataset read in 0:00:02.526845. Found 7617 examples.
# Training model...
# Model trained in 0:00:00.569903
# Compiling model...
# [INFO 26-09-11 08:15:32.7381 UTC kernel.cc:1233] Loading model from path /tmp/tmppd0g6vhz/model/ with prefix 7c16763aa67e428a
# [INFO 26-09-11 08:15:32.7398 UTC quick_scorer_extended.cc:911] The binary was compiled without AVX2 support, but your CPU supports it. Enable it for faster model inference.
# [INFO 26-09-11 08:15:32.7399 UTC abstract_model.cc:1362] Engine "GradientBoostedTreesQuickScorerExtended" built
# [INFO 26-09-11 08:15:32.7399 UTC kernel.cc:1061] Use fast generic engine
# Model compiled.
# CPU times: user 7.53 s, sys: 440 ms, total: 7.97 s
# Wall time: 6.12 s

# %%
# Evaluate the model
evaluate = model.evaluate(val_ds, return_dict=True)
print()

for name, value in evaluate.items():
    print(f"{name}: {value:.4f}")
# Out:
# WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 1/2 [==============>...............] - ETA: 2s - loss: 0.0000e+00 - accuracy: 0.9490
# 2/2 [==============================] - 3s 7ms/step - loss: 0.0000e+00 - accuracy: 0.9489
# loss: 0.0000
# accuracy: 0.9489

# %%
# Model Summary
model.summary()
# Out:
# Model: "gradient_boosted_trees_model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
# =================================================================
# Total params: 1 (1.00 Byte)
# Trainable params: 0 (0.00 Byte)
# Non-trainable params: 1 (1.00 Byte)
# _________________________________________________________________
# Type: "GRADIENT_BOOSTED_TREES"
# Task: CLASSIFICATION
# Label: "__LABEL"
#
# Input Features (18):
# 	10Percentile
# 	90Percentile
# 	Energy
# 	Entropy
# 	InterquartileRange
# 	Kurtosis
# 	Maximum
# 	Mean
# 	MeanAbsoluteDeviation
# 	Median
# 	Minimum
# 	Range
# 	RobustMeanAbsoluteDeviation
# 	RootMeanSquared
# 	Skewness
# 	TotalEnergy
# 	Uniformity
# 	Variance
#
# Trained with weights
#
# Variable Importance: INV_MEAN_MIN_DEPTH:
#     1.                "90Percentile"  0.275224 ################
#     2.                      "Median"  0.259358 #############
#     3.                        "Mean"  0.239453 ##########
#     4.                     "Maximum"  0.224984 ########
#     5.                 "TotalEnergy"  0.202201 ####
#     6.                "10Percentile"  0.200179 ####
#     7.             "RootMeanSquared"  0.196334 ###
#     8.                    "Skewness"  0.194262 ###
#     9.                  "Uniformity"  0.190729 ##
#    10.                      "Energy"  0.187617 ##
#    11.                       "Range"  0.184255 #
#    12.                     "Entropy"  0.178166
#    13.          "InterquartileRange"  0.176588
#    14.                     "Minimum"  0.176366
#    15.                    "Kurtosis"  0.173911
#    16.                    "Variance"  0.173450
#    17. "RobustMeanAbsoluteDeviation"  0.172964
#    18.       "MeanAbsoluteDeviation"  0.172776
#
# Variable Importance: NUM_AS_ROOT:
#     1.    "90Percentile"  9.000000 ################
#     2.            "Mean"  5.000000 ########
#     3.     "TotalEnergy"  5.000000 ########
#     4.         "Maximum"  4.000000 ######
#     5. "RootMeanSquared"  4.000000 ######
#     6.          "Energy"  2.000000 ##
#     7.    "10Percentile"  1.000000
#     8.          "Median"  1.000000
#
# Variable Importance: NUM_NODES:
#     1.                      "Median" 108.000000 ################
#     2.                "90Percentile" 98.000000 ##############
#     3.                    "Skewness" 88.000000 ############
#     4.                     "Maximum" 87.000000 ############
#     5.                        "Mean" 63.000000 ########
#     6.                  "Uniformity" 60.000000 #######
#     7.                       "Range" 59.000000 #######
#     8.                "10Percentile" 39.000000 ####
#     9.                     "Entropy" 39.000000 ####
#    10.                     "Minimum" 28.000000 ##
#    11.                    "Kurtosis" 27.000000 ##
#    12.                    "Variance" 23.000000 #
#    13.                 "TotalEnergy" 21.000000 #
#    14.          "InterquartileRange" 19.000000
#    15.             "RootMeanSquared" 18.000000
#    16.                      "Energy" 16.000000
#    17.       "MeanAbsoluteDeviation" 15.000000
#    18. "RobustMeanAbsoluteDeviation" 15.000000
#
# Variable Importance: SUM_SCORE:
#     1.             "RootMeanSquared" 1549.557048 ################
#     2.                "90Percentile" 1532.084049 ###############
#     3.                      "Energy" 913.953744 #########
#     4.                 "TotalEnergy" 841.650942 ########
#     5.                     "Maximum" 486.975409 ####
#     6.                      "Median" 467.922692 ####
#     7.                  "Uniformity" 279.755711 ##
#     8.                        "Mean" 253.171785 ##
#     9.                    "Skewness" 243.270084 ##
#    10.          "InterquartileRange" 182.337197 #
#    11.                       "Range" 154.405360 #
#    12.                "10Percentile" 148.744973 #
#    13.                    "Kurtosis" 101.123024
#    14.                     "Minimum" 94.480210
#    15.                     "Entropy" 83.657272
#    16.                    "Variance" 81.507124
#    17. "RobustMeanAbsoluteDeviation" 49.413086
#    18.       "MeanAbsoluteDeviation" 40.061356
#
#
#
# Loss: BINOMIAL_LOG_LIKELIHOOD
# Validation loss value: 0.499736
# Number of trees per iteration: 1
# Node format: NOT_SET
# Number of trees: 31
# Total number of nodes: 1677
#
# Number of nodes by tree:
# Count: 31 Average: 54.0968 StdDev: 6.96236
# Min: 39 Max: 63 Ignored: 0
# ----------------------------------------------
# [ 39, 40) 1   3.23%   3.23% #
# [ 40, 41) 0   0.00%   3.23%
# [ 41, 42) 2   6.45%   9.68% ###
# [ 42, 44) 2   6.45%  16.13% ###
# [ 44, 45) 0   0.00%  16.13%
# [ 45, 46) 1   3.23%  19.35% #
# [ 46, 47) 0   0.00%  19.35%
# [ 47, 49) 2   6.45%  25.81% ###
# [ 49, 50) 1   3.23%  29.03% #
# [ 50, 51) 0   0.00%  29.03%
# [ 51, 52) 0   0.00%  29.03%
# [ 52, 54) 0   0.00%  29.03%
# [ 54, 55) 0   0.00%  29.03%
# [ 55, 56) 3   9.68%  38.71% ####
# [ 56, 57) 0   0.00%  38.71%
# [ 57, 59) 7  22.58%  61.29% #########
# [ 59, 60) 8  25.81%  87.10% ##########
# [ 60, 61) 0   0.00%  87.10%
# [ 61, 62) 3   9.68%  96.77% ####
# [ 62, 63] 1   3.23% 100.00% #
#
# Depth by leafs:
# Count: 854 Average: 4.87119 StdDev: 0.410391
# Min: 2 Max: 5 Ignored: 0
# ----------------------------------------------
# [ 2, 3)   4   0.47%   0.47%
# [ 3, 4)  12   1.41%   1.87%
# [ 4, 5)  74   8.67%  10.54% #
# [ 5, 5] 764  89.46% 100.00% ##########
#
# Number of training obs by leaf:
# Count: 854 Average: 249.343 StdDev: 604.452
# Min: 5 Max: 5832 Ignored: 0
# ----------------------------------------------
# [    5,  296) 709  83.02%  83.02% ##########
# [  296,  587)  55   6.44%  89.46% #
# [  587,  879)  21   2.46%  91.92%
# [  879, 1170)  20   2.34%  94.26%
# [ 1170, 1462)   5   0.59%  94.85%
# [ 1462, 1753)   9   1.05%  95.90%
# [ 1753, 2044)   5   0.59%  96.49%
# [ 2044, 2336)  14   1.64%  98.13%
# [ 2336, 2627)   4   0.47%  98.59%
# [ 2627, 2919)   1   0.12%  98.71%
# [ 2919, 3210)   3   0.35%  99.06%
# [ 3210, 3501)   1   0.12%  99.18%
# [ 3501, 3793)   2   0.23%  99.41%
# [ 3793, 4084)   3   0.35%  99.77%
# [ 4084, 4376)   0   0.00%  99.77%
# [ 4376, 4667)   1   0.12%  99.88%
# [ 4667, 4958)   0   0.00%  99.88%
# [ 4958, 5250)   0   0.00%  99.88%
# [ 5250, 5541)   0   0.00%  99.88%
# [ 5541, 5832]   1   0.12% 100.00%
#
# Attribute in nodes:
# 	108 : Median [NUMERICAL]
# 	98 : 90Percentile [NUMERICAL]
# 	88 : Skewness [NUMERICAL]
# 	87 : Maximum [NUMERICAL]
# 	63 : Mean [NUMERICAL]
# 	60 : Uniformity [NUMERICAL]
# 	59 : Range [NUMERICAL]
# 	39 : Entropy [NUMERICAL]
# 	39 : 10Percentile [NUMERICAL]
# 	28 : Minimum [NUMERICAL]
# 	27 : Kurtosis [NUMERICAL]
# 	23 : Variance [NUMERICAL]
# 	21 : TotalEnergy [NUMERICAL]
# 	19 : InterquartileRange [NUMERICAL]
# 	18 : RootMeanSquared [NUMERICAL]
# 	16 : Energy [NUMERICAL]
# 	15 : RobustMeanAbsoluteDeviation [NUMERICAL]
# 	15 : MeanAbsoluteDeviation [NUMERICAL]
#
# Attribute in nodes with depth <= 0:
# 	9 : 90Percentile [NUMERICAL]
# 	5 : TotalEnergy [NUMERICAL]
# 	5 : Mean [NUMERICAL]
# 	4 : RootMeanSquared [NUMERICAL]
# 	4 : Maximum [NUMERICAL]
# 	2 : Energy [NUMERICAL]
# 	1 : Median [NUMERICAL]
# 	1 : 10Percentile [NUMERICAL]
#
# Attribute in nodes with depth <= 1:
# 	24 : Median [NUMERICAL]
# 	16 : 90Percentile [NUMERICAL]
# 	14 : Mean [NUMERICAL]
# 	10 : 10Percentile [NUMERICAL]
# 	8 : Maximum [NUMERICAL]
# 	6 : TotalEnergy [NUMERICAL]
# 	4 : Skewness [NUMERICAL]
# 	4 : RootMeanSquared [NUMERICAL]
# 	3 : Uniformity [NUMERICAL]
# 	3 : Energy [NUMERICAL]
# 	1 : Entropy [NUMERICAL]
#
# Attribute in nodes with depth <= 2:
# 	32 : Mean [NUMERICAL]
# 	31 : Median [NUMERICAL]
# 	26 : Maximum [NUMERICAL]
# 	26 : 90Percentile [NUMERICAL]
# 	15 : Uniformity [NUMERICAL]
# 	15 : Skewness [NUMERICAL]
# 	13 : Range [NUMERICAL]
# 	13 : 10Percentile [NUMERICAL]
# 	8 : TotalEnergy [NUMERICAL]
# 	8 : RootMeanSquared [NUMERICAL]
# 	7 : Energy [NUMERICAL]
# 	6 : Entropy [NUMERICAL]
# 	5 : Minimum [NUMERICAL]
# 	4 : InterquartileRange [NUMERICAL]
# 	2 : Variance [NUMERICAL]
# 	1 : RobustMeanAbsoluteDeviation [NUMERICAL]
# 	1 : MeanAbsoluteDeviation [NUMERICAL]
#
# Attribute in nodes with depth <= 3:
# 	61 : Median [NUMERICAL]
# 	59 : 90Percentile [NUMERICAL]
# 	51 : Skewness [NUMERICAL]
# 	50 : Mean [NUMERICAL]
# 	50 : Maximum [NUMERICAL]
# 	25 : Range [NUMERICAL]
# 	24 : Uniformity [NUMERICAL]
# 	20 : 10Percentile [NUMERICAL]
# 	16 : Entropy [NUMERICAL]
# 	13 : InterquartileRange [NUMERICAL]
# 	12 : TotalEnergy [NUMERICAL]
# 	11 : RootMeanSquared [NUMERICAL]
# 	11 : Minimum [NUMERICAL]
# 	11 : Energy [NUMERICAL]
# 	9 : Kurtosis [NUMERICAL]
# 	7 : Variance [NUMERICAL]
# 	6 : RobustMeanAbsoluteDeviation [NUMERICAL]
# 	5 : MeanAbsoluteDeviation [NUMERICAL]
#
# Attribute in nodes with depth <= 5:
# 	108 : Median [NUMERICAL]
# 	98 : 90Percentile [NUMERICAL]
# 	88 : Skewness [NUMERICAL]
# 	87 : Maximum [NUMERICAL]
# 	63 : Mean [NUMERICAL]
# 	60 : Uniformity [NUMERICAL]
# 	59 : Range [NUMERICAL]
# 	39 : Entropy [NUMERICAL]
# 	39 : 10Percentile [NUMERICAL]
# 	28 : Minimum [NUMERICAL]
# 	27 : Kurtosis [NUMERICAL]
# 	23 : Variance [NUMERICAL]
# 	21 : TotalEnergy [NUMERICAL]
# 	19 : InterquartileRange [NUMERICAL]
# 	18 : RootMeanSquared [NUMERICAL]
# 	16 : Energy [NUMERICAL]
# 	15 : RobustMeanAbsoluteDeviation [NUMERICAL]
# 	15 : MeanAbsoluteDeviation [NUMERICAL]
#
# Condition type in nodes:
# 	823 : HigherCondition
# Condition type in nodes with depth <= 0:
# 	31 : HigherCondition
# Condition type in nodes with depth <= 1:
# 	93 : HigherCondition
# Condition type in nodes with depth <= 2:
# 	213 : HigherCondition
# Condition type in nodes with depth <= 3:
# 	441 : HigherCondition
# Condition type in nodes with depth <= 5:
# 	823 : HigherCondition
#
# Training logs:
# Number of iteration to final model: 31
# 	Iter:1 train-loss:1.256210 valid-loss:1.262372  train-accuracy:0.898538 valid-accuracy:0.868554
# 	Iter:2 train-loss:1.146849 valid-loss:1.161547  train-accuracy:0.909510 valid-accuracy:0.868867
# 	Iter:3 train-loss:1.058334 valid-loss:1.079823  train-accuracy:0.911931 valid-accuracy:0.862295
# 	Iter:4 train-loss:0.979932 valid-loss:1.006383  train-accuracy:0.915773 valid-accuracy:0.868867
# 	Iter:5 train-loss:0.914044 valid-loss:0.937220  train-accuracy:0.917293 valid-accuracy:0.872998
# 	Iter:6 train-loss:0.857112 valid-loss:0.878300  train-accuracy:0.921255 valid-accuracy:0.892339
# 	Iter:16 train-loss:0.541000 valid-loss:0.585840  train-accuracy:0.927710 valid-accuracy:0.899225
# 	Iter:26 train-loss:0.412953 valid-loss:0.512572  train-accuracy:0.945257 valid-accuracy:0.901979
# 	Iter:36 train-loss:0.343273 valid-loss:0.503683  train-accuracy:0.949205 valid-accuracy:0.912682
# 	Iter:46 train-loss:0.292135 valid-loss:0.508385  train-accuracy:0.961575 valid-accuracy:0.904733
# 	Iter:56 train-loss:0.248968 valid-loss:0.507293  train-accuracy:0.974890 valid-accuracy:0.906110

# %%
# Model features
model.make_inspector().features()
# Out:
# ["10Percentile" (1; #0),
#  "90Percentile" (1; #1),
#  "Energy" (1; #2),
#  "Entropy" (1; #3),
#  "InterquartileRange" (1; #4),
#  "Kurtosis" (1; #5),
#  "Maximum" (1; #6),
#  "Mean" (1; #7),
#  "MeanAbsoluteDeviation" (1; #8),
#  "Median" (1; #9),
#  "Minimum" (1; #10),
#  "Range" (1; #11),
#  "RobustMeanAbsoluteDeviation" (1; #12),
#  "RootMeanSquared" (1; #13),
#  "Skewness" (1; #14),
#  "TotalEnergy" (1; #15),
#  "Uniformity" (1; #16),
#  "Variance" (1; #17)]

# %%
# Feature importance
model.make_inspector().variable_importances()
# Out:
# {'INV_MEAN_MIN_DEPTH': [("90Percentile" (1; #1), 0.2752241891194622),
#   ("Median" (1; #9), 0.2593575686298411),
#   ("Mean" (1; #7), 0.23945322413286038),
#   ("Maximum" (1; #6), 0.22498445388577318),
#   ("TotalEnergy" (1; #15), 0.2022014149213268),
#   ("10Percentile" (1; #0), 0.2001788239321024),
#   ("RootMeanSquared" (1; #13), 0.19633371616823456),
#   ("Skewness" (1; #14), 0.19426217338508986),
#   ("Uniformity" (1; #16), 0.19072939083906815),
#   ("Energy" (1; #2), 0.18761741033586848),
#   ("Range" (1; #11), 0.18425495551632273),
#   ("Entropy" (1; #3), 0.17816577729974917),
#   ("InterquartileRange" (1; #4), 0.17658780760895654),
#   ("Minimum" (1; #10), 0.17636559687859193),
#   ("Kurtosis" (1; #5), 0.17391142787729813),
#   ("Variance" (1; #17), 0.1734501921731829),
#   ("RobustMeanAbsoluteDeviation" (1; #12), 0.17296399124216788),
#   ("MeanAbsoluteDeviation" (1; #8), 0.17277558311342653)],
#  'NUM_AS_ROOT': [("90Percentile" (1; #1), 9.0),
#   ("Mean" (1; #7), 5.0),
#   ("TotalEnergy" (1; #15), 5.0),
#   ("Maximum" (1; #6), 4.0),
#   ("RootMeanSquared" (1; #13), 4.0),
#   ("Energy" (1; #2), 2.0),
#   ("10Percentile" (1; #0), 1.0),
#   ("Median" (1; #9), 1.0)],
#  'SUM_SCORE': [("RootMeanSquared" (1; #13), 1549.5570476706498),
#   ("90Percentile" (1; #1), 1532.0840485705808),
#   ("Energy" (1; #2), 913.9537441848341),
#   ("TotalEnergy" (1; #15), 841.6509420995383),
#   ("Maximum" (1; #6), 486.9754087073328),
#   ("Median" (1; #9), 467.92269185499094),
#   ("Uniformity" (1; #16), 279.7557111416135),
#   ("Mean" (1; #7), 253.17178501669014),
#   ("Skewness" (1; #14), 243.2700842500072),
#   ("InterquartileRange" (1; #4), 182.33719689249438),
#   ("Range" (1; #11), 154.4053604018982),
#   ("10Percentile" (1; #0), 148.74497315609167),
#   ("Kurtosis" (1; #5), 101.12302374746756),
#   ("Minimum" (1; #10), 94.48020988545765),
#   ("Entropy" (1; #3), 83.65727191717937),
#   ("Variance" (1; #17), 81.50712369516242),
#   ("RobustMeanAbsoluteDeviation" (1; #12), 49.41308633716566),
#   ("MeanAbsoluteDeviation" (1; #8), 40.061356483806485)],
#  'NUM_NODES': [("Median" (1; #9), 108.0),
#   ("90Percentile" (1; #1), 98.0),
#   ("Skewness" (1; #14), 88.0),
#   ("Maximum" (1; #6), 87.0),
#   ("Mean" (1; #7), 63.0),
#   ("Uniformity" (1; #16), 60.0),
#   ("Range" (1; #11), 59.0),
#   ("10Percentile" (1; #0), 39.0),
#   ("Entropy" (1; #3), 39.0),
#   ("Minimum" (1; #10), 28.0),
#   ("Kurtosis" (1; #5), 27.0),
#   ("Variance" (1; #17), 23.0),
#   ("TotalEnergy" (1; #15), 21.0),
#   ("InterquartileRange" (1; #4), 19.0),
#   ("RootMeanSquared" (1; #13), 18.0),
#   ("Energy" (1; #2), 16.0),
#   ("MeanAbsoluteDeviation" (1; #8), 15.0),
#   ("RobustMeanAbsoluteDeviation" (1; #12), 15.0)]}

# %%
# Model self evaluation
model.make_inspector().evaluation()
# Out:
# Evaluation(num_examples=None, accuracy=0.9026676416397095, loss=0.4997362494468689, rmse=None, ndcg=None, aucs=None, auuc=None, qini=None)

# %%
logs = model.make_inspector().training_logs()

plt.figure(figsize=(12, 4))
plt.subplot(1, 2, 1)
plt.plot([log.num_trees for log in logs], [log.evaluation.accuracy for log in logs])
plt.xlabel("Number of trees")
plt.ylabel("Accuracy (out-of-bag)")
plt.subplot(1, 2, 2)
plt.plot([log.num_trees for log in logs], [log.evaluation.loss for log in logs])
plt.xlabel("Number of trees")
plt.ylabel("Logloss (out-of-bag)")
plt.show()

# %% [markdown]
# Calculate the score of our hold-out validation dataset

# %%
predictions = model.predict(val_ds)
y_true      = validation_data["label"]

from sklearn.metrics import roc_auc_score
ROC_AUC = roc_auc_score(y_true, predictions)
print("The ROC AUC score is %.5f" % ROC_AUC )
# Out:
# 1/2 [==============>...............] - ETA: 0s
# 2/2 [==============================] - 0s 3ms/step
# The ROC AUC score is 0.99392

# %%
# Compute binary classification metrics with sklearn
import numpy as np
from sklearn.metrics import (
    accuracy_score,
    precision_score,
    recall_score,
    f1_score,
    roc_auc_score,
    average_precision_score,
    confusion_matrix,
    classification_report,
    matthews_corrcoef,
    log_loss,
    brier_score_loss,
)

# Get predictions (probabilities or class labels)
preds = model.predict(test_ds)
# If model outputs probabilities, convert to labels by threshold 0.5
if preds.ndim == 2:
    # For TFDF classification, preds may be class probabilities with shape (N, 2)
    if preds.shape[1] == 2:
        pos_probs = preds[:, 1]
    else:
        # If single-probability column (positive class)
        pos_probs = preds[:, -1]
    y_pred = (pos_probs >= 0.5).astype(int)
else:
    # Already class labels
    y_pred = preds.astype(int)
    pos_probs = None

# Ground truth labels (must be 0/1 integers)
y_true = test_data["label"].astype(int).to_numpy()

# Core metrics
metrics = {}
metrics["accuracy"] = accuracy_score(y_true, y_pred)
metrics["precision"] = precision_score(y_true, y_pred, zero_division=0)
metrics["recall"] = recall_score(y_true, y_pred, zero_division=0)
metrics["f1"] = f1_score(y_true, y_pred, zero_division=0)
metrics["mcc"] = matthews_corrcoef(y_true, y_pred)

# Probabilistic metrics (only if we have probabilities)
if pos_probs is not None:
    metrics["roc_auc"] = roc_auc_score(y_true, pos_probs)
    metrics["pr_auc"] = average_precision_score(y_true, pos_probs)
    metrics["log_loss"] = log_loss(y_true, pos_probs, labels=[0,1])
    metrics["brier_score"] = brier_score_loss(y_true, pos_probs)

# Confusion matrix and detailed report
cm = confusion_matrix(y_true, y_pred, labels=[0,1])
report = classification_report(y_true, y_pred, digits=4)

print("Sklearn binary metrics:")
for k, v in metrics.items():
    print(f"{k}: {v:.4f}")
print("\nConfusion matrix:\n", cm)
print("\nClassification report:\n", report)
# Out:
# 1/3 [=========>....................] - ETA: 0s
# 3/3 [==============================] - 0s 3ms/step
# Sklearn binary metrics:
# accuracy: 0.9549
# precision: 0.7331
# recall: 0.8590
# f1: 0.7911
# mcc: 0.7690
# roc_auc: 0.9482
# pr_auc: 0.8674
# log_loss: 0.2028
# brier_score: 0.0462
#
# Confusion matrix:
#  [[1985   71]
#  [  32  195]]
#
# Classification report:
#                precision    recall  f1-score   support
#
#            0     0.9841    0.9655    0.9747      2056
#            1     0.7331    0.8590    0.7911       227
#
#     accuracy                         0.9549      2283
#    macro avg     0.8586    0.9122    0.8829      2283
# weighted avg     0.9592    0.9549    0.9565      2283
