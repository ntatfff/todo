# %%
# Import packages and modules
import numpy  as np
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow_decision_forests as tfdf

from sklearn.model_selection import train_test_split
# Out:
# 2026-09-11 08:16:20.024515: I tensorflow/core/util/port.cc:113] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2026-09-11 08:16:20.065161: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2026-09-11 08:16:24.458774: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
# Check the version of TensorFlow Decision Forests
print("Found TensorFlow Decision Forests v" + tfdf.__version__)
# Out:
# Found TensorFlow Decision Forests v1.9.1

# %%
datasetPath = "dataset/10p/all/kernel3/"

# %%
# Parameters
datasetPath = "dataset/10p/gldm/kernel5/"

# %%
# train/validation/test = 70/10/20
train_data = pd.read_csv(f"{datasetPath}dataset.train.csv")
validation_data = pd.read_csv(f"{datasetPath}dataset.validation.csv")
test_data = pd.read_csv(f"{datasetPath}dataset.test.csv")

# %%
from sklearn.utils.class_weight import compute_class_weight

# tinh class weight tren tap train
classes = np.array([0, 1])
weights = compute_class_weight(class_weight="balanced", classes=classes, y=train_data["label"])
class_weight = {0: weights[0], 1: weights[1]}

# gan sample_weight cho tung dong
train_data["sample_weight"] = train_data["label"].map(class_weight)
validation_data["sample_weight"] = validation_data["label"].map(class_weight)
test_data["sample_weight"] = test_data["label"].map(class_weight)

# Convert the dataset into a TensorFlow dataset.
train_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    train_data, label="label", weight="sample_weight"
)         
val_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    validation_data, label="label", weight="sample_weight"
)
test_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    test_data, label="label", weight="sample_weight"
)
# Out:
# 2026-09-11 08:16:37.282940: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:984] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2026-09-11 08:16:37.284029: W tensorflow/core/common_runtime/gpu/gpu_device.cc:2251] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...

# %%
import keras

# %%
# %%time

# Train a Gradient Boosted Trees model.
model = tfdf.keras.GradientBoostedTreesModel()

# Add evaluation metrics
model.compile(
    metrics=["accuracy"]
)
model.fit(x=train_ds)

# # Train a Gradient Boosted Trees model.
# model = tfdf.keras.GradientBoostedTreesModel(num_trees=1500)
# model.fit(train_ds)
# Out:
# Use /tmp/tmp8lishkuz as temporary training directory
# Reading training dataset...
# [WARNING 26-09-11 08:16:37.3984 UTC gradient_boosted_trees.cc:1840] "goss_alpha" set but "sampling_method" not equal to "GOSS".
# [WARNING 26-09-11 08:16:37.3985 UTC gradient_boosted_trees.cc:1851] "goss_beta" set but "sampling_method" not equal to "GOSS".
# [WARNING 26-09-11 08:16:37.3985 UTC gradient_boosted_trees.cc:1865] "selective_gradient_boosting_ratio" set but "sampling_method" not equal to "SELGB".
# Training dataset read in 0:00:02.473141. Found 7617 examples.
# Training model...
# Model trained in 0:00:00.618889
# Compiling model...
# [INFO 26-09-11 08:16:40.5107 UTC kernel.cc:1233] Loading model from path /tmp/tmp8lishkuz/model/ with prefix a5cd07447cf5400f
# [INFO 26-09-11 08:16:40.5131 UTC quick_scorer_extended.cc:911] The binary was compiled without AVX2 support, but your CPU supports it. Enable it for faster model inference.
# [INFO 26-09-11 08:16:40.5133 UTC abstract_model.cc:1362] Engine "GradientBoostedTreesQuickScorerExtended" built
# [INFO 26-09-11 08:16:40.5133 UTC kernel.cc:1061] Use fast generic engine
# Model compiled.
# CPU times: user 7.58 s, sys: 435 ms, total: 8.01 s
# Wall time: 6.14 s

# %%
# Evaluate the model
evaluate = model.evaluate(val_ds, return_dict=True)
print()

for name, value in evaluate.items():
    print(f"{name}: {value:.4f}")
# Out:
# WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 1/2 [==============>...............] - ETA: 2s - loss: 0.0000e+00 - accuracy: 0.9860
# 2/2 [==============================] - 3s 7ms/step - loss: 0.0000e+00 - accuracy: 0.9861
# loss: 0.0000
# accuracy: 0.9861

# %%
# Model Summary
model.summary()
# Out:
# Model: "gradient_boosted_trees_model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
# =================================================================
# Total params: 1 (1.00 Byte)
# Trainable params: 0 (0.00 Byte)
# Non-trainable params: 1 (1.00 Byte)
# _________________________________________________________________
# Type: "GRADIENT_BOOSTED_TREES"
# Task: CLASSIFICATION
# Label: "__LABEL"
#
# Input Features (14):
# 	DependenceEntropy
# 	DependenceNonUniformity
# 	DependenceNonUniformityNormalized
# 	DependenceVariance
# 	GrayLevelNonUniformity
# 	GrayLevelVariance
# 	HighGrayLevelEmphasis
# 	LargeDependenceEmphasis
# 	LargeDependenceHighGrayLevelEmphasis
# 	LargeDependenceLowGrayLevelEmphasis
# 	LowGrayLevelEmphasis
# 	SmallDependenceEmphasis
# 	SmallDependenceHighGrayLevelEmphasis
# 	SmallDependenceLowGrayLevelEmphasis
#
# Trained with weights
#
# Variable Importance: INV_MEAN_MIN_DEPTH:
#     1. "LargeDependenceHighGrayLevelEmphasis"  0.374306 ################
#     2.                "HighGrayLevelEmphasis"  0.370153 ###############
#     3.                    "DependenceEntropy"  0.239080 #####
#     4. "SmallDependenceHighGrayLevelEmphasis"  0.204905 ##
#     5.               "GrayLevelNonUniformity"  0.186097
#     6.  "LargeDependenceLowGrayLevelEmphasis"  0.184829
#     7.  "SmallDependenceLowGrayLevelEmphasis"  0.184398
#     8.                    "GrayLevelVariance"  0.182601
#     9.              "SmallDependenceEmphasis"  0.178902
#    10.                 "LowGrayLevelEmphasis"  0.177451
#    11.              "LargeDependenceEmphasis"  0.176503
#    12.                   "DependenceVariance"  0.176105
#    13.              "DependenceNonUniformity"  0.175979
#    14.    "DependenceNonUniformityNormalized"  0.175233
#
# Variable Importance: NUM_AS_ROOT:
#     1.                "HighGrayLevelEmphasis" 26.000000 ################
#     2. "LargeDependenceHighGrayLevelEmphasis" 17.000000 ##########
#     3. "SmallDependenceHighGrayLevelEmphasis"  3.000000 #
#     4.  "LargeDependenceLowGrayLevelEmphasis"  1.000000
#
# Variable Importance: NUM_NODES:
#     1.                    "DependenceEntropy" 208.000000 ################
#     2.                "HighGrayLevelEmphasis" 206.000000 ###############
#     3. "LargeDependenceHighGrayLevelEmphasis" 186.000000 ##############
#     4. "SmallDependenceHighGrayLevelEmphasis" 137.000000 #########
#     5.  "SmallDependenceLowGrayLevelEmphasis" 80.000000 ####
#     6.  "LargeDependenceLowGrayLevelEmphasis" 77.000000 ####
#     7.               "GrayLevelNonUniformity" 68.000000 ###
#     8.                    "GrayLevelVariance" 52.000000 ##
#     9.                 "LowGrayLevelEmphasis" 46.000000 #
#    10.              "SmallDependenceEmphasis" 44.000000 #
#    11.                   "DependenceVariance" 42.000000 #
#    12.              "LargeDependenceEmphasis" 37.000000
#    13.    "DependenceNonUniformityNormalized" 29.000000
#    14.              "DependenceNonUniformity" 26.000000
#
# Variable Importance: SUM_SCORE:
#     1.                "HighGrayLevelEmphasis" 5021.452404 ################
#     2. "LargeDependenceHighGrayLevelEmphasis" 1441.165152 ####
#     3.                    "DependenceEntropy" 688.052595 ##
#     4. "SmallDependenceHighGrayLevelEmphasis" 345.214891
#     5.  "LargeDependenceLowGrayLevelEmphasis" 247.442407
#     6.  "SmallDependenceLowGrayLevelEmphasis" 138.227469
#     7.               "GrayLevelNonUniformity" 132.817816
#     8.              "DependenceNonUniformity" 107.087733
#     9.                    "GrayLevelVariance" 97.279146
#    10.    "DependenceNonUniformityNormalized" 94.103947
#    11.                 "LowGrayLevelEmphasis" 89.737756
#    12.              "SmallDependenceEmphasis" 89.073768
#    13.                   "DependenceVariance" 68.825212
#    14.              "LargeDependenceEmphasis" 42.743683
#
#
#
# Loss: BINOMIAL_LOG_LIKELIHOOD
# Validation loss value: 0.510587
# Number of trees per iteration: 1
# Node format: NOT_SET
# Number of trees: 47
# Total number of nodes: 2523
#
# Number of nodes by tree:
# Count: 47 Average: 53.6809 StdDev: 6.51384
# Min: 37 Max: 61 Ignored: 0
# ----------------------------------------------
# [ 37, 38) 2   4.26%   4.26% ##
# [ 38, 39) 0   0.00%   4.26%
# [ 39, 40) 0   0.00%   4.26%
# [ 40, 42) 1   2.13%   6.38% #
# [ 42, 43) 0   0.00%   6.38%
# [ 43, 44) 3   6.38%  12.77% ###
# [ 44, 45) 0   0.00%  12.77%
# [ 45, 47) 2   4.26%  17.02% ##
# [ 47, 48) 1   2.13%  19.15% #
# [ 48, 49) 0   0.00%  19.15%
# [ 49, 50) 2   4.26%  23.40% ##
# [ 50, 52) 4   8.51%  31.91% ####
# [ 52, 53) 0   0.00%  31.91%
# [ 53, 54) 2   4.26%  36.17% ##
# [ 54, 55) 0   0.00%  36.17%
# [ 55, 57) 9  19.15%  55.32% ##########
# [ 57, 58) 7  14.89%  70.21% ########
# [ 58, 59) 0   0.00%  70.21%
# [ 59, 60) 7  14.89%  85.11% ########
# [ 60, 61] 7  14.89% 100.00% ########
#
# Depth by leafs:
# Count: 1285 Average: 4.86615 StdDev: 0.427623
# Min: 2 Max: 5 Ignored: 0
# ----------------------------------------------
# [ 2, 3)    4   0.31%   0.31%
# [ 3, 4)   31   2.41%   2.72%
# [ 4, 5)   98   7.63%  10.35% #
# [ 5, 5] 1152  89.65% 100.00% ##########
#
# Number of training obs by leaf:
# Count: 1285 Average: 251.24 StdDev: 678.697
# Min: 5 Max: 5777 Ignored: 0
# ----------------------------------------------
# [    5,  293) 1102  85.76%  85.76% ##########
# [  293,  582)   48   3.74%  89.49%
# [  582,  870)   32   2.49%  91.98%
# [  870, 1159)   30   2.33%  94.32%
# [ 1159, 1448)   11   0.86%  95.18%
# [ 1448, 1736)    4   0.31%  95.49%
# [ 1736, 2025)   10   0.78%  96.26%
# [ 2025, 2314)    5   0.39%  96.65%
# [ 2314, 2602)    5   0.39%  97.04%
# [ 2602, 2891)    4   0.31%  97.35%
# [ 2891, 3180)    5   0.39%  97.74%
# [ 3180, 3468)   12   0.93%  98.68%
# [ 3468, 3757)    9   0.70%  99.38%
# [ 3757, 4046)    3   0.23%  99.61%
# [ 4046, 4334)    1   0.08%  99.69%
# [ 4334, 4623)    1   0.08%  99.77%
# [ 4623, 4912)    1   0.08%  99.84%
# [ 4912, 5200)    1   0.08%  99.92%
# [ 5200, 5489)    0   0.00%  99.92%
# [ 5489, 5777]    1   0.08% 100.00%
#
# Attribute in nodes:
# 	208 : DependenceEntropy [NUMERICAL]
# 	206 : HighGrayLevelEmphasis [NUMERICAL]
# 	186 : LargeDependenceHighGrayLevelEmphasis [NUMERICAL]
# 	137 : SmallDependenceHighGrayLevelEmphasis [NUMERICAL]
# 	80 : SmallDependenceLowGrayLevelEmphasis [NUMERICAL]
# 	77 : LargeDependenceLowGrayLevelEmphasis [NUMERICAL]
# 	68 : GrayLevelNonUniformity [NUMERICAL]
# 	52 : GrayLevelVariance [NUMERICAL]
# 	46 : LowGrayLevelEmphasis [NUMERICAL]
# 	44 : SmallDependenceEmphasis [NUMERICAL]
# 	42 : DependenceVariance [NUMERICAL]
# 	37 : LargeDependenceEmphasis [NUMERICAL]
# 	29 : DependenceNonUniformityNormalized [NUMERICAL]
# 	26 : DependenceNonUniformity [NUMERICAL]
#
# Attribute in nodes with depth <= 0:
# 	26 : HighGrayLevelEmphasis [NUMERICAL]
# 	17 : LargeDependenceHighGrayLevelEmphasis [NUMERICAL]
# 	3 : SmallDependenceHighGrayLevelEmphasis [NUMERICAL]
# 	1 : LargeDependenceLowGrayLevelEmphasis [NUMERICAL]
#
# Attribute in nodes with depth <= 1:
# 	55 : HighGrayLevelEmphasis [NUMERICAL]
# 	46 : LargeDependenceHighGrayLevelEmphasis [NUMERICAL]
# 	14 : DependenceEntropy [NUMERICAL]
# 	7 : GrayLevelNonUniformity [NUMERICAL]
# 	5 : SmallDependenceHighGrayLevelEmphasis [NUMERICAL]
# 	4 : SmallDependenceLowGrayLevelEmphasis [NUMERICAL]
# 	3 : LargeDependenceLowGrayLevelEmphasis [NUMERICAL]
# 	3 : LargeDependenceEmphasis [NUMERICAL]
# 	2 : GrayLevelVariance [NUMERICAL]
# 	1 : LowGrayLevelEmphasis [NUMERICAL]
# 	1 : DependenceNonUniformity [NUMERICAL]
#
# Attribute in nodes with depth <= 2:
# 	73 : HighGrayLevelEmphasis [NUMERICAL]
# 	70 : DependenceEntropy [NUMERICAL]
# 	67 : LargeDependenceHighGrayLevelEmphasis [NUMERICAL]
# 	28 : SmallDependenceHighGrayLevelEmphasis [NUMERICAL]
# 	15 : GrayLevelVariance [NUMERICAL]
# 	14 : LargeDependenceLowGrayLevelEmphasis [NUMERICAL]
# 	13 : SmallDependenceLowGrayLevelEmphasis [NUMERICAL]
# 	10 : GrayLevelNonUniformity [NUMERICAL]
# 	8 : SmallDependenceEmphasis [NUMERICAL]
# 	6 : DependenceNonUniformityNormalized [NUMERICAL]
# 	6 : DependenceNonUniformity [NUMERICAL]
# 	5 : LowGrayLevelEmphasis [NUMERICAL]
# 	5 : LargeDependenceEmphasis [NUMERICAL]
# 	5 : DependenceVariance [NUMERICAL]
#
# Attribute in nodes with depth <= 3:
# 	116 : HighGrayLevelEmphasis [NUMERICAL]
# 	116 : DependenceEntropy [NUMERICAL]
# 	115 : LargeDependenceHighGrayLevelEmphasis [NUMERICAL]
# 	81 : SmallDependenceHighGrayLevelEmphasis [NUMERICAL]
# 	35 : SmallDependenceLowGrayLevelEmphasis [NUMERICAL]
# 	33 : LargeDependenceLowGrayLevelEmphasis [NUMERICAL]
# 	30 : GrayLevelVariance [NUMERICAL]
# 	28 : SmallDependenceEmphasis [NUMERICAL]
# 	24 : GrayLevelNonUniformity [NUMERICAL]
# 	23 : LowGrayLevelEmphasis [NUMERICAL]
# 	19 : LargeDependenceEmphasis [NUMERICAL]
# 	16 : DependenceVariance [NUMERICAL]
# 	14 : DependenceNonUniformityNormalized [NUMERICAL]
# 	12 : DependenceNonUniformity [NUMERICAL]
#
# Attribute in nodes with depth <= 5:
# 	208 : DependenceEntropy [NUMERICAL]
# 	206 : HighGrayLevelEmphasis [NUMERICAL]
# 	186 : LargeDependenceHighGrayLevelEmphasis [NUMERICAL]
# 	137 : SmallDependenceHighGrayLevelEmphasis [NUMERICAL]
# 	80 : SmallDependenceLowGrayLevelEmphasis [NUMERICAL]
# 	77 : LargeDependenceLowGrayLevelEmphasis [NUMERICAL]
# 	68 : GrayLevelNonUniformity [NUMERICAL]
# 	52 : GrayLevelVariance [NUMERICAL]
# 	46 : LowGrayLevelEmphasis [NUMERICAL]
# 	44 : SmallDependenceEmphasis [NUMERICAL]
# 	42 : DependenceVariance [NUMERICAL]
# 	37 : LargeDependenceEmphasis [NUMERICAL]
# 	29 : DependenceNonUniformityNormalized [NUMERICAL]
# 	26 : DependenceNonUniformity [NUMERICAL]
#
# Condition type in nodes:
# 	1238 : HigherCondition
# Condition type in nodes with depth <= 0:
# 	47 : HigherCondition
# Condition type in nodes with depth <= 1:
# 	141 : HigherCondition
# Condition type in nodes with depth <= 2:
# 	325 : HigherCondition
# Condition type in nodes with depth <= 3:
# 	662 : HigherCondition
# Condition type in nodes with depth <= 5:
# 	1238 : HigherCondition
#
# Training logs:
# Number of iteration to final model: 47
# 	Iter:1 train-loss:1.238009 valid-loss:1.263848  train-accuracy:0.920654 valid-accuracy:0.859174
# 	Iter:2 train-loss:1.116055 valid-loss:1.159282  train-accuracy:0.932823 valid-accuracy:0.869697
# 	Iter:3 train-loss:1.013522 valid-loss:1.075641  train-accuracy:0.933322 valid-accuracy:0.885139
# 	Iter:4 train-loss:0.926386 valid-loss:0.997674  train-accuracy:0.936495 valid-accuracy:0.888146
# 	Iter:5 train-loss:0.852597 valid-loss:0.931230  train-accuracy:0.943494 valid-accuracy:0.873046
# 	Iter:6 train-loss:0.787167 valid-loss:0.877404  train-accuracy:0.941778 valid-accuracy:0.873046
# 	Iter:16 train-loss:0.426278 valid-loss:0.620781  train-accuracy:0.959159 valid-accuracy:0.906595
# 	Iter:26 train-loss:0.282794 valid-loss:0.537878  train-accuracy:0.967607 valid-accuracy:0.908098
# 	Iter:36 train-loss:0.214853 valid-loss:0.519206  train-accuracy:0.977533 valid-accuracy:0.912608
# 	Iter:46 train-loss:0.176316 valid-loss:0.510850  train-accuracy:0.982963 valid-accuracy:0.923540
# 	Iter:56 train-loss:0.148917 valid-loss:0.517624  train-accuracy:0.986761 valid-accuracy:0.924292
# 	Iter:66 train-loss:0.128933 valid-loss:0.540263  train-accuracy:0.989357 valid-accuracy:0.914863
# 	Iter:76 train-loss:0.114367 valid-loss:0.562925  train-accuracy:0.990208 valid-accuracy:0.914111

# %%
# Model features
model.make_inspector().features()
# Out:
# ["DependenceEntropy" (1; #0),
#  "DependenceNonUniformity" (1; #1),
#  "DependenceNonUniformityNormalized" (1; #2),
#  "DependenceVariance" (1; #3),
#  "GrayLevelNonUniformity" (1; #4),
#  "GrayLevelVariance" (1; #5),
#  "HighGrayLevelEmphasis" (1; #6),
#  "LargeDependenceEmphasis" (1; #7),
#  "LargeDependenceHighGrayLevelEmphasis" (1; #8),
#  "LargeDependenceLowGrayLevelEmphasis" (1; #9),
#  "LowGrayLevelEmphasis" (1; #10),
#  "SmallDependenceEmphasis" (1; #11),
#  "SmallDependenceHighGrayLevelEmphasis" (1; #12),
#  "SmallDependenceLowGrayLevelEmphasis" (1; #13)]

# %%
# Feature importance
model.make_inspector().variable_importances()
# Out:
# {'INV_MEAN_MIN_DEPTH': [("LargeDependenceHighGrayLevelEmphasis" (1; #8),
#    0.37430566832247675),
#   ("HighGrayLevelEmphasis" (1; #6), 0.3701526626026581),
#   ("DependenceEntropy" (1; #0), 0.23908045069305298),
#   ("SmallDependenceHighGrayLevelEmphasis" (1; #12), 0.20490501440972766),
#   ("GrayLevelNonUniformity" (1; #4), 0.18609673628759701),
#   ("LargeDependenceLowGrayLevelEmphasis" (1; #9), 0.18482893289715444),
#   ("SmallDependenceLowGrayLevelEmphasis" (1; #13), 0.1843984050380451),
#   ("GrayLevelVariance" (1; #5), 0.18260079355446437),
#   ("SmallDependenceEmphasis" (1; #11), 0.17890169028780475),
#   ("LowGrayLevelEmphasis" (1; #10), 0.17745054939960195),
#   ("LargeDependenceEmphasis" (1; #7), 0.17650317300098572),
#   ("DependenceVariance" (1; #3), 0.1761045853188544),
#   ("DependenceNonUniformity" (1; #1), 0.1759791807661885),
#   ("DependenceNonUniformityNormalized" (1; #2), 0.17523314648653557)],
#  'SUM_SCORE': [("HighGrayLevelEmphasis" (1; #6), 5021.452403580008),
#   ("LargeDependenceHighGrayLevelEmphasis" (1; #8), 1441.1651521487508),
#   ("DependenceEntropy" (1; #0), 688.0525954119772),
#   ("SmallDependenceHighGrayLevelEmphasis" (1; #12), 345.2148913983655),
#   ("LargeDependenceLowGrayLevelEmphasis" (1; #9), 247.44240677503288),
#   ("SmallDependenceLowGrayLevelEmphasis" (1; #13), 138.2274686307032),
#   ("GrayLevelNonUniformity" (1; #4), 132.8178159050865),
#   ("DependenceNonUniformity" (1; #1), 107.08773310069616),
#   ("GrayLevelVariance" (1; #5), 97.27914580374006),
#   ("DependenceNonUniformityNormalized" (1; #2), 94.10394650099852),
#   ("LowGrayLevelEmphasis" (1; #10), 89.73775555575214),
#   ("SmallDependenceEmphasis" (1; #11), 89.0737684720593),
#   ("DependenceVariance" (1; #3), 68.8252122721237),
#   ("LargeDependenceEmphasis" (1; #7), 42.74368333470351)],
#  'NUM_AS_ROOT': [("HighGrayLevelEmphasis" (1; #6), 26.0),
#   ("LargeDependenceHighGrayLevelEmphasis" (1; #8), 17.0),
#   ("SmallDependenceHighGrayLevelEmphasis" (1; #12), 3.0),
#   ("LargeDependenceLowGrayLevelEmphasis" (1; #9), 1.0)],
#  'NUM_NODES': [("DependenceEntropy" (1; #0), 208.0),
#   ("HighGrayLevelEmphasis" (1; #6), 206.0),
#   ("LargeDependenceHighGrayLevelEmphasis" (1; #8), 186.0),
#   ("SmallDependenceHighGrayLevelEmphasis" (1; #12), 137.0),
#   ("SmallDependenceLowGrayLevelEmphasis" (1; #13), 80.0),
#   ("LargeDependenceLowGrayLevelEmphasis" (1; #9), 77.0),
#   ("GrayLevelNonUniformity" (1; #4), 68.0),
#   ("GrayLevelVariance" (1; #5), 52.0),
#   ("LowGrayLevelEmphasis" (1; #10), 46.0),
#   ("SmallDependenceEmphasis" (1; #11), 44.0),
#   ("DependenceVariance" (1; #3), 42.0),
#   ("LargeDependenceEmphasis" (1; #7), 37.0),
#   ("DependenceNonUniformityNormalized" (1; #2), 29.0),
#   ("DependenceNonUniformity" (1; #1), 26.0)]}

# %%
# Model self evaluation
model.make_inspector().evaluation()
# Out:
# Evaluation(num_examples=None, accuracy=0.9227885603904724, loss=0.5105870366096497, rmse=None, ndcg=None, aucs=None, auuc=None, qini=None)

# %%
logs = model.make_inspector().training_logs()

plt.figure(figsize=(12, 4))
plt.subplot(1, 2, 1)
plt.plot([log.num_trees for log in logs], [log.evaluation.accuracy for log in logs])
plt.xlabel("Number of trees")
plt.ylabel("Accuracy (out-of-bag)")
plt.subplot(1, 2, 2)
plt.plot([log.num_trees for log in logs], [log.evaluation.loss for log in logs])
plt.xlabel("Number of trees")
plt.ylabel("Logloss (out-of-bag)")
plt.show()

# %% [markdown]
# Calculate the score of our hold-out validation dataset

# %%
predictions = model.predict(val_ds)
y_true      = validation_data["label"]

from sklearn.metrics import roc_auc_score
ROC_AUC = roc_auc_score(y_true, predictions)
print("The ROC AUC score is %.5f" % ROC_AUC )
# Out:
# 1/2 [==============>...............] - ETA: 0s
# 2/2 [==============================] - 0s 3ms/step
# The ROC AUC score is 0.99878

# %%
# Compute binary classification metrics with sklearn
import numpy as np
from sklearn.metrics import (
    accuracy_score,
    precision_score,
    recall_score,
    f1_score,
    roc_auc_score,
    average_precision_score,
    confusion_matrix,
    classification_report,
    matthews_corrcoef,
    log_loss,
    brier_score_loss,
)

# Get predictions (probabilities or class labels)
preds = model.predict(test_ds)
# If model outputs probabilities, convert to labels by threshold 0.5
if preds.ndim == 2:
    # For TFDF classification, preds may be class probabilities with shape (N, 2)
    if preds.shape[1] == 2:
        pos_probs = preds[:, 1]
    else:
        # If single-probability column (positive class)
        pos_probs = preds[:, -1]
    y_pred = (pos_probs >= 0.5).astype(int)
else:
    # Already class labels
    y_pred = preds.astype(int)
    pos_probs = None

# Ground truth labels (must be 0/1 integers)
y_true = test_data["label"].astype(int).to_numpy()

# Core metrics
metrics = {}
metrics["accuracy"] = accuracy_score(y_true, y_pred)
metrics["precision"] = precision_score(y_true, y_pred, zero_division=0)
metrics["recall"] = recall_score(y_true, y_pred, zero_division=0)
metrics["f1"] = f1_score(y_true, y_pred, zero_division=0)
metrics["mcc"] = matthews_corrcoef(y_true, y_pred)

# Probabilistic metrics (only if we have probabilities)
if pos_probs is not None:
    metrics["roc_auc"] = roc_auc_score(y_true, pos_probs)
    metrics["pr_auc"] = average_precision_score(y_true, pos_probs)
    metrics["log_loss"] = log_loss(y_true, pos_probs, labels=[0,1])
    metrics["brier_score"] = brier_score_loss(y_true, pos_probs)

# Confusion matrix and detailed report
cm = confusion_matrix(y_true, y_pred, labels=[0,1])
report = classification_report(y_true, y_pred, digits=4)

print("Sklearn binary metrics:")
for k, v in metrics.items():
    print(f"{k}: {v:.4f}")
print("\nConfusion matrix:\n", cm)
print("\nClassification report:\n", report)
# Out:
# 1/3 [=========>....................] - ETA: 0s
# 3/3 [==============================] - 0s 3ms/step
# Sklearn binary metrics:
# accuracy: 0.9619
# precision: 0.8017
# recall: 0.8194
# f1: 0.8105
# mcc: 0.7893
# roc_auc: 0.9537
# pr_auc: 0.8701
# log_loss: 0.1255
# brier_score: 0.0315
#
# Confusion matrix:
#  [[2010   46]
#  [  41  186]]
#
# Classification report:
#                precision    recall  f1-score   support
#
#            0     0.9800    0.9776    0.9788      2056
#            1     0.8017    0.8194    0.8105       227
#
#     accuracy                         0.9619      2283
#    macro avg     0.8909    0.8985    0.8946      2283
# weighted avg     0.9623    0.9619    0.9621      2283
