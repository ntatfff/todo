# %%
# Import packages and modules
import numpy  as np
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow_decision_forests as tfdf

from sklearn.model_selection import train_test_split
# Out:
# 2026-07-04 09:00:43.667785: I tensorflow/core/util/port.cc:113] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2026-07-04 09:00:43.708786: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2026-07-04 09:00:47.960619: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
# Check the version of TensorFlow Decision Forests
print("Found TensorFlow Decision Forests v" + tfdf.__version__)
# Out:
# Found TensorFlow Decision Forests v1.9.1

# %%
datasetPath = 'dataset/firstorder/kernel5-radius5/dataset.csv'

# %%
# Parameters
datasetPath = "dataset/glszm/kernel5-radius5/200.dataset.csv"

# %%
# train/validation/test = 70/10/20
dataset = pd.read_csv(datasetPath)

train_data, temp_data = train_test_split(dataset, test_size=0.3, random_state=42)
validation_data, test_data = train_test_split(temp_data, test_size=2/3, random_state=42)

# %%
from sklearn.utils.class_weight import compute_class_weight

# tinh class weight tren tap train
classes = np.array([0, 1])
weights = compute_class_weight(class_weight="balanced", classes=classes, y=train_data["label"])
class_weight = {0: weights[0], 1: weights[1]}

# gan sample_weight cho tung dong
train_data["sample_weight"] = train_data["label"].map(class_weight)
validation_data["sample_weight"] = validation_data["label"].map(class_weight)
test_data["sample_weight"] = test_data["label"].map(class_weight)

# Convert the dataset into a TensorFlow dataset.
train_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    train_data, label="label", weight="sample_weight"
)         
val_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    validation_data, label="label", weight="sample_weight"
)
test_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    test_data, label="label", weight="sample_weight"
)
# Out:
# 2026-07-04 09:01:00.309362: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:984] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2026-07-04 09:01:00.310825: W tensorflow/core/common_runtime/gpu/gpu_device.cc:2251] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...

# %%
import keras

# %%
# %%time

# Train a Gradient Boosted Trees model.
model = tfdf.keras.GradientBoostedTreesModel()

# Add evaluation metrics
model.compile(
    metrics=["accuracy"]
)
model.fit(x=train_ds)

# # Train a Gradient Boosted Trees model.
# model = tfdf.keras.GradientBoostedTreesModel(num_trees=1500)
# model.fit(train_ds)
# Out:
# Use /tmp/tmppb41bml2 as temporary training directory
# Reading training dataset...
# [WARNING 26-07-04 09:01:00.4632 UTC gradient_boosted_trees.cc:1840] "goss_alpha" set but "sampling_method" not equal to "GOSS".
# [WARNING 26-07-04 09:01:00.4633 UTC gradient_boosted_trees.cc:1851] "goss_beta" set but "sampling_method" not equal to "GOSS".
# [WARNING 26-07-04 09:01:00.4633 UTC gradient_boosted_trees.cc:1865] "selective_gradient_boosting_ratio" set but "sampling_method" not equal to "SELGB".
# Training dataset read in 0:00:03.108155. Found 157360 examples.
# Training model...
# Model trained in 0:00:28.338324
# Compiling model...
# [INFO 26-07-04 09:01:31.9401 UTC kernel.cc:1233] Loading model from path /tmp/tmppb41bml2/model/ with prefix 2a4a23c49cea4da2
# [INFO 26-07-04 09:01:31.9497 UTC quick_scorer_extended.cc:911] The binary was compiled without AVX2 support, but your CPU supports it. Enable it for faster model inference.
# [INFO 26-07-04 09:01:31.9504 UTC abstract_model.cc:1362] Engine "GradientBoostedTreesQuickScorerExtended" built
# [INFO 26-07-04 09:01:31.9504 UTC kernel.cc:1061] Use fast generic engine
# Model compiled.
# CPU times: user 3min 25s, sys: 2.66 s, total: 3min 28s
# Wall time: 34.5 s

# %%
# Evaluate the model
evaluate = model.evaluate(val_ds, return_dict=True)
print()

for name, value in evaluate.items():
    print(f"{name}: {value:.4f}")
# Out:
# WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
#  1/23 [>.............................] - ETA: 1:05 - loss: 0.0000e+00 - accuracy: 0.8750
# 11/23 [=============>................] - ETA: 0s - loss: 0.0000e+00 - accuracy: 0.8716
# 23/23 [==============================] - ETA: 0s - loss: 0.0000e+00 - accuracy: 0.8752
# 23/23 [==============================] - 3s 5ms/step - loss: 0.0000e+00 - accuracy: 0.8752
# loss: 0.0000
# accuracy: 0.8752

# %%
# Model Summary
model.summary()
# Out:
# Model: "gradient_boosted_trees_model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
# =================================================================
# Total params: 1 (1.00 Byte)
# Trainable params: 0 (0.00 Byte)
# Non-trainable params: 1 (1.00 Byte)
# _________________________________________________________________
# Type: "GRADIENT_BOOSTED_TREES"
# Task: CLASSIFICATION
# Label: "__LABEL"
#
# Input Features (16):
# 	GrayLevelNonUniformity
# 	GrayLevelNonUniformityNormalized
# 	GrayLevelVariance
# 	HighGrayLevelZoneEmphasis
# 	LargeAreaEmphasis
# 	LargeAreaHighGrayLevelEmphasis
# 	LargeAreaLowGrayLevelEmphasis
# 	LowGrayLevelZoneEmphasis
# 	SizeZoneNonUniformity
# 	SizeZoneNonUniformityNormalized
# 	SmallAreaEmphasis
# 	SmallAreaHighGrayLevelEmphasis
# 	SmallAreaLowGrayLevelEmphasis
# 	ZoneEntropy
# 	ZonePercentage
# 	ZoneVariance
#
# Trained with weights
#
# Variable Importance: INV_MEAN_MIN_DEPTH:
#     1.   "LargeAreaHighGrayLevelEmphasis"  0.274896 ################
#     2.           "GrayLevelNonUniformity"  0.232466 #########
#     3.    "LargeAreaLowGrayLevelEmphasis"  0.222457 #######
#     4.        "HighGrayLevelZoneEmphasis"  0.222107 #######
#     5.         "LowGrayLevelZoneEmphasis"  0.206577 #####
#     6.                     "ZoneVariance"  0.199456 ###
#     7.   "SmallAreaHighGrayLevelEmphasis"  0.192155 ##
#     8.                "GrayLevelVariance"  0.188831 ##
#     9.                      "ZoneEntropy"  0.185085 #
#    10.  "SizeZoneNonUniformityNormalized"  0.183401 #
#    11. "GrayLevelNonUniformityNormalized"  0.182431 #
#    12.    "SmallAreaLowGrayLevelEmphasis"  0.181345 #
#    13.                   "ZonePercentage"  0.176558
#    14.                "LargeAreaEmphasis"  0.176084
#    15.                "SmallAreaEmphasis"  0.175217
#    16.            "SizeZoneNonUniformity"  0.174348
#
# Variable Importance: NUM_AS_ROOT:
#     1.  "LargeAreaHighGrayLevelEmphasis" 71.000000 ################
#     2.       "HighGrayLevelZoneEmphasis" 30.000000 ######
#     3.          "GrayLevelNonUniformity" 25.000000 #####
#     4.        "LowGrayLevelZoneEmphasis" 22.000000 ####
#     5.   "LargeAreaLowGrayLevelEmphasis" 20.000000 ####
#     6.   "SmallAreaLowGrayLevelEmphasis"  5.000000
#     7. "SizeZoneNonUniformityNormalized"  4.000000
#     8.  "SmallAreaHighGrayLevelEmphasis"  4.000000
#     9.                  "ZonePercentage"  3.000000
#    10.               "GrayLevelVariance"  2.000000
#    11.                     "ZoneEntropy"  2.000000
#    12.               "SmallAreaEmphasis"  1.000000
#
# Variable Importance: NUM_NODES:
#     1.   "LargeAreaHighGrayLevelEmphasis" 561.000000 ################
#     2.        "HighGrayLevelZoneEmphasis" 528.000000 ##############
#     3.           "GrayLevelNonUniformity" 526.000000 ##############
#     4.    "LargeAreaLowGrayLevelEmphasis" 508.000000 ##############
#     5.         "LowGrayLevelZoneEmphasis" 411.000000 ##########
#     6.                     "ZoneVariance" 407.000000 ##########
#     7.   "SmallAreaHighGrayLevelEmphasis" 385.000000 #########
#     8.                      "ZoneEntropy" 329.000000 #######
#     9.                "GrayLevelVariance" 318.000000 ######
#    10.    "SmallAreaLowGrayLevelEmphasis" 258.000000 ####
#    11. "GrayLevelNonUniformityNormalized" 247.000000 ####
#    12.  "SizeZoneNonUniformityNormalized" 206.000000 ##
#    13.                "SmallAreaEmphasis" 150.000000
#    14.                "LargeAreaEmphasis" 147.000000
#    15.            "SizeZoneNonUniformity" 144.000000
#    16.                   "ZonePercentage" 133.000000
#
# Variable Importance: SUM_SCORE:
#     1.        "HighGrayLevelZoneEmphasis" 46872.371732 ################
#     2.           "GrayLevelNonUniformity" 21179.302273 #######
#     3.    "LargeAreaLowGrayLevelEmphasis" 13884.465242 ####
#     4.  "SizeZoneNonUniformityNormalized" 11291.862008 ###
#     5.   "SmallAreaHighGrayLevelEmphasis" 7836.858118 ##
#     6.         "LowGrayLevelZoneEmphasis" 6585.776191 ##
#     7.                     "ZoneVariance" 4129.594492 #
#     8.   "LargeAreaHighGrayLevelEmphasis" 3918.630660 #
#     9.                "SmallAreaEmphasis" 3816.455533 #
#    10.                      "ZoneEntropy" 3034.307241
#    11.    "SmallAreaLowGrayLevelEmphasis" 2656.531685
#    12.                "GrayLevelVariance" 2274.714879
#    13.            "SizeZoneNonUniformity" 1117.805770
#    14. "GrayLevelNonUniformityNormalized" 1114.716330
#    15.                   "ZonePercentage" 615.932056
#    16.                "LargeAreaEmphasis" 584.248801
#
#
#
# Loss: BINOMIAL_LOG_LIKELIHOOD
# Validation loss value: 0.629348
# Number of trees per iteration: 1
# Node format: NOT_SET
# Number of trees: 189
# Total number of nodes: 10705
#
# Number of nodes by tree:
# Count: 189 Average: 56.6402 StdDev: 6.67917
# Min: 35 Max: 63 Ignored: 0
# ----------------------------------------------
# [ 35, 36)  2   1.06%   1.06%
# [ 36, 37)  0   0.00%   1.06%
# [ 37, 39)  1   0.53%   1.59%
# [ 39, 40)  0   0.00%   1.59%
# [ 40, 42)  4   2.12%   3.70% #
# [ 42, 43)  0   0.00%   3.70%
# [ 43, 45)  4   2.12%   5.82% #
# [ 45, 46)  3   1.59%   7.41% #
# [ 46, 48) 15   7.94%  15.34% ###
# [ 48, 49)  0   0.00%  15.34%
# [ 49, 50)  7   3.70%  19.05% #
# [ 50, 52) 10   5.29%  24.34% ##
# [ 52, 53)  0   0.00%  24.34%
# [ 53, 55)  5   2.65%  26.98% #
# [ 55, 56) 16   8.47%  35.45% ###
# [ 56, 58) 20  10.58%  46.03% ####
# [ 58, 59)  0   0.00%  46.03%
# [ 59, 61) 18   9.52%  55.56% ####
# [ 61, 62) 35  18.52%  74.07% #######
# [ 62, 63] 49  25.93% 100.00% ##########
#
# Depth by leafs:
# Count: 5447 Average: 4.91867 StdDev: 0.352538
# Min: 2 Max: 5 Ignored: 0
# ----------------------------------------------
# [ 2, 3)   23   0.42%   0.42%
# [ 3, 4)   66   1.21%   1.63%
# [ 4, 5)  242   4.44%   6.08%
# [ 5, 5] 5116  93.92% 100.00% ##########
#
# Number of training obs by leaf:
# Count: 5447 Average: 4915.53 StdDev: 15770.5
# Min: 5 Max: 136092 Ignored: 0
# ----------------------------------------------
# [      5,   6809) 4722  86.69%  86.69% ##########
# [   6809,  13613)  272   4.99%  91.68% #
# [  13613,  20418)  125   2.29%  93.98%
# [  20418,  27222)   66   1.21%  95.19%
# [  27222,  34027)   60   1.10%  96.29%
# [  34027,  40831)   28   0.51%  96.81%
# [  40831,  47635)   26   0.48%  97.28%
# [  47635,  54440)   14   0.26%  97.54%
# [  54440,  61244)   16   0.29%  97.83%
# [  61244,  68049)    9   0.17%  98.00%
# [  68049,  74853)   11   0.20%  98.20%
# [  74853,  81657)   18   0.33%  98.53%
# [  81657,  88462)    7   0.13%  98.66%
# [  88462,  95266)   15   0.28%  98.94%
# [  95266, 102071)    9   0.17%  99.10%
# [ 102071, 108875)   13   0.24%  99.34%
# [ 108875, 115679)   12   0.22%  99.56%
# [ 115679, 122484)   11   0.20%  99.76%
# [ 122484, 129288)    7   0.13%  99.89%
# [ 129288, 136092]    6   0.11% 100.00%
#
# Attribute in nodes:
# 	561 : LargeAreaHighGrayLevelEmphasis [NUMERICAL]
# 	528 : HighGrayLevelZoneEmphasis [NUMERICAL]
# 	526 : GrayLevelNonUniformity [NUMERICAL]
# 	508 : LargeAreaLowGrayLevelEmphasis [NUMERICAL]
# 	411 : LowGrayLevelZoneEmphasis [NUMERICAL]
# 	407 : ZoneVariance [NUMERICAL]
# 	385 : SmallAreaHighGrayLevelEmphasis [NUMERICAL]
# 	329 : ZoneEntropy [NUMERICAL]
# 	318 : GrayLevelVariance [NUMERICAL]
# 	258 : SmallAreaLowGrayLevelEmphasis [NUMERICAL]
# 	247 : GrayLevelNonUniformityNormalized [NUMERICAL]
# 	206 : SizeZoneNonUniformityNormalized [NUMERICAL]
# 	150 : SmallAreaEmphasis [NUMERICAL]
# 	147 : LargeAreaEmphasis [NUMERICAL]
# 	144 : SizeZoneNonUniformity [NUMERICAL]
# 	133 : ZonePercentage [NUMERICAL]
#
# Attribute in nodes with depth <= 0:
# 	71 : LargeAreaHighGrayLevelEmphasis [NUMERICAL]
# 	30 : HighGrayLevelZoneEmphasis [NUMERICAL]
# 	25 : GrayLevelNonUniformity [NUMERICAL]
# 	22 : LowGrayLevelZoneEmphasis [NUMERICAL]
# 	20 : LargeAreaLowGrayLevelEmphasis [NUMERICAL]
# 	5 : SmallAreaLowGrayLevelEmphasis [NUMERICAL]
# 	4 : SmallAreaHighGrayLevelEmphasis [NUMERICAL]
# 	4 : SizeZoneNonUniformityNormalized [NUMERICAL]
# 	3 : ZonePercentage [NUMERICAL]
# 	2 : ZoneEntropy [NUMERICAL]
# 	2 : GrayLevelVariance [NUMERICAL]
# 	1 : SmallAreaEmphasis [NUMERICAL]
#
# Attribute in nodes with depth <= 1:
# 	138 : LargeAreaHighGrayLevelEmphasis [NUMERICAL]
# 	93 : GrayLevelNonUniformity [NUMERICAL]
# 	68 : LargeAreaLowGrayLevelEmphasis [NUMERICAL]
# 	59 : HighGrayLevelZoneEmphasis [NUMERICAL]
# 	41 : ZoneVariance [NUMERICAL]
# 	41 : LowGrayLevelZoneEmphasis [NUMERICAL]
# 	28 : GrayLevelVariance [NUMERICAL]
# 	27 : SmallAreaHighGrayLevelEmphasis [NUMERICAL]
# 	20 : SizeZoneNonUniformityNormalized [NUMERICAL]
# 	14 : GrayLevelNonUniformityNormalized [NUMERICAL]
# 	11 : LargeAreaEmphasis [NUMERICAL]
# 	8 : SmallAreaLowGrayLevelEmphasis [NUMERICAL]
# 	6 : ZoneEntropy [NUMERICAL]
# 	6 : SmallAreaEmphasis [NUMERICAL]
# 	5 : ZonePercentage [NUMERICAL]
# 	2 : SizeZoneNonUniformity [NUMERICAL]
#
# Attribute in nodes with depth <= 2:
# 	196 : LargeAreaHighGrayLevelEmphasis [NUMERICAL]
# 	156 : GrayLevelNonUniformity [NUMERICAL]
# 	153 : LargeAreaLowGrayLevelEmphasis [NUMERICAL]
# 	148 : HighGrayLevelZoneEmphasis [NUMERICAL]
# 	108 : ZoneVariance [NUMERICAL]
# 	94 : LowGrayLevelZoneEmphasis [NUMERICAL]
# 	80 : SmallAreaHighGrayLevelEmphasis [NUMERICAL]
# 	67 : GrayLevelVariance [NUMERICAL]
# 	64 : ZoneEntropy [NUMERICAL]
# 	62 : GrayLevelNonUniformityNormalized [NUMERICAL]
# 	48 : SizeZoneNonUniformityNormalized [NUMERICAL]
# 	37 : SmallAreaLowGrayLevelEmphasis [NUMERICAL]
# 	25 : ZonePercentage [NUMERICAL]
# 	23 : LargeAreaEmphasis [NUMERICAL]
# 	21 : SizeZoneNonUniformity [NUMERICAL]
# 	18 : SmallAreaEmphasis [NUMERICAL]
#
# Attribute in nodes with depth <= 3:
# 	318 : LargeAreaHighGrayLevelEmphasis [NUMERICAL]
# 	294 : GrayLevelNonUniformity [NUMERICAL]
# 	284 : LargeAreaLowGrayLevelEmphasis [NUMERICAL]
# 	283 : HighGrayLevelZoneEmphasis [NUMERICAL]
# 	229 : ZoneVariance [NUMERICAL]
# 	209 : LowGrayLevelZoneEmphasis [NUMERICAL]
# 	185 : SmallAreaHighGrayLevelEmphasis [NUMERICAL]
# 	158 : GrayLevelVariance [NUMERICAL]
# 	157 : ZoneEntropy [NUMERICAL]
# 	122 : GrayLevelNonUniformityNormalized [NUMERICAL]
# 	107 : SmallAreaLowGrayLevelEmphasis [NUMERICAL]
# 	102 : SizeZoneNonUniformityNormalized [NUMERICAL]
# 	67 : SmallAreaEmphasis [NUMERICAL]
# 	65 : LargeAreaEmphasis [NUMERICAL]
# 	60 : ZonePercentage [NUMERICAL]
# 	60 : SizeZoneNonUniformity [NUMERICAL]
#
# Attribute in nodes with depth <= 5:
# 	561 : LargeAreaHighGrayLevelEmphasis [NUMERICAL]
# 	528 : HighGrayLevelZoneEmphasis [NUMERICAL]
# 	526 : GrayLevelNonUniformity [NUMERICAL]
# 	508 : LargeAreaLowGrayLevelEmphasis [NUMERICAL]
# 	411 : LowGrayLevelZoneEmphasis [NUMERICAL]
# 	407 : ZoneVariance [NUMERICAL]
# 	385 : SmallAreaHighGrayLevelEmphasis [NUMERICAL]
# 	329 : ZoneEntropy [NUMERICAL]
# 	318 : GrayLevelVariance [NUMERICAL]
# 	258 : SmallAreaLowGrayLevelEmphasis [NUMERICAL]
# 	247 : GrayLevelNonUniformityNormalized [NUMERICAL]
# 	206 : SizeZoneNonUniformityNormalized [NUMERICAL]
# 	150 : SmallAreaEmphasis [NUMERICAL]
# 	147 : LargeAreaEmphasis [NUMERICAL]
# 	144 : SizeZoneNonUniformity [NUMERICAL]
# 	133 : ZonePercentage [NUMERICAL]
#
# Condition type in nodes:
# 	5258 : HigherCondition
# Condition type in nodes with depth <= 0:
# 	189 : HigherCondition
# Condition type in nodes with depth <= 1:
# 	567 : HigherCondition
# Condition type in nodes with depth <= 2:
# 	1300 : HigherCondition
# Condition type in nodes with depth <= 3:
# 	2700 : HigherCondition
# Condition type in nodes with depth <= 5:
# 	5258 : HigherCondition
#
# Training logs:
# Number of iteration to final model: 189
# 	Iter:1 train-loss:1.296155 valid-loss:1.295936  train-accuracy:0.813199 valid-accuracy:0.820262
# 	Iter:2 train-loss:1.220217 valid-loss:1.220776  train-accuracy:0.818673 valid-accuracy:0.822309
# 	Iter:3 train-loss:1.155626 valid-loss:1.156173  train-accuracy:0.823690 valid-accuracy:0.826552
# 	Iter:4 train-loss:1.099439 valid-loss:1.102151  train-accuracy:0.830689 valid-accuracy:0.825619
# 	Iter:5 train-loss:1.050400 valid-loss:1.053856  train-accuracy:0.836491 valid-accuracy:0.833274
# 	Iter:6 train-loss:1.006256 valid-loss:1.011026  train-accuracy:0.839960 valid-accuracy:0.835234
# 	Iter:16 train-loss:0.778134 valid-loss:0.794410  train-accuracy:0.853060 valid-accuracy:0.843215
# 	Iter:26 train-loss:0.693041 valid-loss:0.720154  train-accuracy:0.858683 valid-accuracy:0.851028
# 	Iter:36 train-loss:0.651594 valid-loss:0.686103  train-accuracy:0.863719 valid-accuracy:0.855418
# 	Iter:46 train-loss:0.627022 valid-loss:0.669887  train-accuracy:0.868235 valid-accuracy:0.859212
# 	Iter:56 train-loss:0.610299 valid-loss:0.659926  train-accuracy:0.871261 valid-accuracy:0.859660
# 	Iter:66 train-loss:0.596723 valid-loss:0.653307  train-accuracy:0.874083 valid-accuracy:0.860256
# 	Iter:76 train-loss:0.584237 valid-loss:0.648103  train-accuracy:0.877268 valid-accuracy:0.861626
# 	Iter:86 train-loss:0.573849 valid-loss:0.644001  train-accuracy:0.880289 valid-accuracy:0.863786
# 	Iter:96 train-loss:0.565098 valid-loss:0.642528  train-accuracy:0.882660 valid-accuracy:0.862076
# 	Iter:106 train-loss:0.555032 valid-loss:0.637267  train-accuracy:0.884635 valid-accuracy:0.864549
# 	Iter:116 train-loss:0.545490 valid-loss:0.635379  train-accuracy:0.887453 valid-accuracy:0.864401
# 	Iter:126 train-loss:0.539513 valid-loss:0.634667  train-accuracy:0.888474 valid-accuracy:0.865752
# 	Iter:136 train-loss:0.532333 valid-loss:0.634034  train-accuracy:0.890425 valid-accuracy:0.865639
# 	Iter:146 train-loss:0.524964 valid-loss:0.631684  train-accuracy:0.892586 valid-accuracy:0.866678
# 	Iter:156 train-loss:0.519793 valid-loss:0.632173  train-accuracy:0.893914 valid-accuracy:0.865905
# 	Iter:166 train-loss:0.514277 valid-loss:0.631837  train-accuracy:0.895485 valid-accuracy:0.865955
# 	Iter:176 train-loss:0.507236 valid-loss:0.631408  train-accuracy:0.897771 valid-accuracy:0.866648
# 	Iter:186 train-loss:0.501100 valid-loss:0.629463  train-accuracy:0.899409 valid-accuracy:0.866666
# 	Iter:196 train-loss:0.496615 valid-loss:0.630251  train-accuracy:0.900493 valid-accuracy:0.866848
# 	Iter:206 train-loss:0.492071 valid-loss:0.630321  train-accuracy:0.901584 valid-accuracy:0.867508
# 	Iter:216 train-loss:0.486295 valid-loss:0.629918  train-accuracy:0.902968 valid-accuracy:0.867937

# %%
# Model features
model.make_inspector().features()
# Out:
# ["GrayLevelNonUniformity" (1; #0),
#  "GrayLevelNonUniformityNormalized" (1; #1),
#  "GrayLevelVariance" (1; #2),
#  "HighGrayLevelZoneEmphasis" (1; #3),
#  "LargeAreaEmphasis" (1; #4),
#  "LargeAreaHighGrayLevelEmphasis" (1; #5),
#  "LargeAreaLowGrayLevelEmphasis" (1; #6),
#  "LowGrayLevelZoneEmphasis" (1; #7),
#  "SizeZoneNonUniformity" (1; #8),
#  "SizeZoneNonUniformityNormalized" (1; #9),
#  "SmallAreaEmphasis" (1; #10),
#  "SmallAreaHighGrayLevelEmphasis" (1; #11),
#  "SmallAreaLowGrayLevelEmphasis" (1; #12),
#  "ZoneEntropy" (1; #13),
#  "ZonePercentage" (1; #14),
#  "ZoneVariance" (1; #15)]

# %%
# Feature importance
model.make_inspector().variable_importances()
# Out:
# {'INV_MEAN_MIN_DEPTH': [("LargeAreaHighGrayLevelEmphasis" (1; #5),
#    0.27489645169929605),
#   ("GrayLevelNonUniformity" (1; #0), 0.23246552333440354),
#   ("LargeAreaLowGrayLevelEmphasis" (1; #6), 0.22245660682501955),
#   ("HighGrayLevelZoneEmphasis" (1; #3), 0.22210728922161152),
#   ("LowGrayLevelZoneEmphasis" (1; #7), 0.20657669841963427),
#   ("ZoneVariance" (1; #15), 0.19945615516042434),
#   ("SmallAreaHighGrayLevelEmphasis" (1; #11), 0.19215509366855993),
#   ("GrayLevelVariance" (1; #2), 0.1888306026657846),
#   ("ZoneEntropy" (1; #13), 0.18508542563343758),
#   ("SizeZoneNonUniformityNormalized" (1; #9), 0.18340149273311382),
#   ("GrayLevelNonUniformityNormalized" (1; #1), 0.18243087447062237),
#   ("SmallAreaLowGrayLevelEmphasis" (1; #12), 0.18134482575181726),
#   ("ZonePercentage" (1; #14), 0.17655751391681934),
#   ("LargeAreaEmphasis" (1; #4), 0.17608443515132088),
#   ("SmallAreaEmphasis" (1; #10), 0.17521735192138996),
#   ("SizeZoneNonUniformity" (1; #8), 0.17434826609804985)],
#  'SUM_SCORE': [("HighGrayLevelZoneEmphasis" (1; #3), 46872.371731575884),
#   ("GrayLevelNonUniformity" (1; #0), 21179.302272634068),
#   ("LargeAreaLowGrayLevelEmphasis" (1; #6), 13884.46524158408),
#   ("SizeZoneNonUniformityNormalized" (1; #9), 11291.86200818231),
#   ("SmallAreaHighGrayLevelEmphasis" (1; #11), 7836.858118140653),
#   ("LowGrayLevelZoneEmphasis" (1; #7), 6585.776190775377),
#   ("ZoneVariance" (1; #15), 4129.59449210338),
#   ("LargeAreaHighGrayLevelEmphasis" (1; #5), 3918.630659883989),
#   ("SmallAreaEmphasis" (1; #10), 3816.4555333635635),
#   ("ZoneEntropy" (1; #13), 3034.307241493597),
#   ("SmallAreaLowGrayLevelEmphasis" (1; #12), 2656.5316850212453),
#   ("GrayLevelVariance" (1; #2), 2274.714879005178),
#   ("SizeZoneNonUniformity" (1; #8), 1117.8057700233094),
#   ("GrayLevelNonUniformityNormalized" (1; #1), 1114.7163304459064),
#   ("ZonePercentage" (1; #14), 615.9320563468477),
#   ("LargeAreaEmphasis" (1; #4), 584.2488012305321)],
#  'NUM_AS_ROOT': [("LargeAreaHighGrayLevelEmphasis" (1; #5), 71.0),
#   ("HighGrayLevelZoneEmphasis" (1; #3), 30.0),
#   ("GrayLevelNonUniformity" (1; #0), 25.0),
#   ("LowGrayLevelZoneEmphasis" (1; #7), 22.0),
#   ("LargeAreaLowGrayLevelEmphasis" (1; #6), 20.0),
#   ("SmallAreaLowGrayLevelEmphasis" (1; #12), 5.0),
#   ("SizeZoneNonUniformityNormalized" (1; #9), 4.0),
#   ("SmallAreaHighGrayLevelEmphasis" (1; #11), 4.0),
#   ("ZonePercentage" (1; #14), 3.0),
#   ("GrayLevelVariance" (1; #2), 2.0),
#   ("ZoneEntropy" (1; #13), 2.0),
#   ("SmallAreaEmphasis" (1; #10), 1.0)],
#  'NUM_NODES': [("LargeAreaHighGrayLevelEmphasis" (1; #5), 561.0),
#   ("HighGrayLevelZoneEmphasis" (1; #3), 528.0),
#   ("GrayLevelNonUniformity" (1; #0), 526.0),
#   ("LargeAreaLowGrayLevelEmphasis" (1; #6), 508.0),
#   ("LowGrayLevelZoneEmphasis" (1; #7), 411.0),
#   ("ZoneVariance" (1; #15), 407.0),
#   ("SmallAreaHighGrayLevelEmphasis" (1; #11), 385.0),
#   ("ZoneEntropy" (1; #13), 329.0),
#   ("GrayLevelVariance" (1; #2), 318.0),
#   ("SmallAreaLowGrayLevelEmphasis" (1; #12), 258.0),
#   ("GrayLevelNonUniformityNormalized" (1; #1), 247.0),
#   ("SizeZoneNonUniformityNormalized" (1; #9), 206.0),
#   ("SmallAreaEmphasis" (1; #10), 150.0),
#   ("LargeAreaEmphasis" (1; #4), 147.0),
#   ("SizeZoneNonUniformity" (1; #8), 144.0),
#   ("ZonePercentage" (1; #14), 133.0)]}

# %%
# Model self evaluation
model.make_inspector().evaluation()
# Out:
# Evaluation(num_examples=None, accuracy=0.8672266006469727, loss=0.62934809923172, rmse=None, ndcg=None, aucs=None, auuc=None, qini=None)

# %%
logs = model.make_inspector().training_logs()

plt.figure(figsize=(12, 4))
plt.subplot(1, 2, 1)
plt.plot([log.num_trees for log in logs], [log.evaluation.accuracy for log in logs])
plt.xlabel("Number of trees")
plt.ylabel("Accuracy (out-of-bag)")
plt.subplot(1, 2, 2)
plt.plot([log.num_trees for log in logs], [log.evaluation.loss for log in logs])
plt.xlabel("Number of trees")
plt.ylabel("Logloss (out-of-bag)")
plt.show()

# %% [markdown]
# Calculate the score of our hold-out validation dataset

# %%
predictions = model.predict(val_ds)
y_true      = validation_data["label"]

from sklearn.metrics import roc_auc_score
ROC_AUC = roc_auc_score(y_true, predictions)
print("The ROC AUC score is %.5f" % ROC_AUC )
# Out:
#  1/23 [>.............................] - ETA: 1s
# 13/23 [===============>..............] - ETA: 0s
# 23/23 [==============================] - 0s 4ms/step
# The ROC AUC score is 0.93423

# %%
# Compute binary classification metrics with sklearn
import numpy as np
from sklearn.metrics import (
    accuracy_score,
    precision_score,
    recall_score,
    f1_score,
    roc_auc_score,
    average_precision_score,
    confusion_matrix,
    classification_report,
    matthews_corrcoef,
    log_loss,
    brier_score_loss,
)

# Get predictions (probabilities or class labels)
preds = model.predict(test_ds)
# If model outputs probabilities, convert to labels by threshold 0.5
if preds.ndim == 2:
    # For TFDF classification, preds may be class probabilities with shape (N, 2)
    if preds.shape[1] == 2:
        pos_probs = preds[:, 1]
    else:
        # If single-probability column (positive class)
        pos_probs = preds[:, -1]
    y_pred = (pos_probs >= 0.5).astype(int)
else:
    # Already class labels
    y_pred = preds.astype(int)
    pos_probs = None

# Ground truth labels (must be 0/1 integers)
y_true = test_data["label"].astype(int).to_numpy()

# Core metrics
metrics = {}
metrics["accuracy"] = accuracy_score(y_true, y_pred)
metrics["precision"] = precision_score(y_true, y_pred, zero_division=0)
metrics["recall"] = recall_score(y_true, y_pred, zero_division=0)
metrics["f1"] = f1_score(y_true, y_pred, zero_division=0)
metrics["mcc"] = matthews_corrcoef(y_true, y_pred)

# Probabilistic metrics (only if we have probabilities)
if pos_probs is not None:
    metrics["roc_auc"] = roc_auc_score(y_true, pos_probs)
    metrics["pr_auc"] = average_precision_score(y_true, pos_probs)
    metrics["log_loss"] = log_loss(y_true, pos_probs, labels=[0,1])
    metrics["brier_score"] = brier_score_loss(y_true, pos_probs)

# Confusion matrix and detailed report
cm = confusion_matrix(y_true, y_pred, labels=[0,1])
report = classification_report(y_true, y_pred, digits=4)

print("Sklearn binary metrics:")
for k, v in metrics.items():
    print(f"{k}: {v:.4f}")
print("\nConfusion matrix:\n", cm)
print("\nClassification report:\n", report)
# Out:
#  1/45 [..............................] - ETA: 33s
# 14/45 [========>.....................] - ETA: 0s
# 27/45 [=================>............] - ETA: 0s
# 39/45 [=========================>....] - ETA: 0s
# 45/45 [==============================] - 1s 4ms/step
# Sklearn binary metrics:
# accuracy: 0.8757
# precision: 0.3191
# recall: 0.8435
# f1: 0.4631
# mcc: 0.4707
# roc_auc: 0.9401
# pr_auc: 0.6505
# log_loss: 0.2796
# brier_score: 0.0871
#
# Confusion matrix:
#  [[36962  5142]
#  [  447  2410]]
#
# Classification report:
#                precision    recall  f1-score   support
#
#            0     0.9881    0.8779    0.9297     42104
#            1     0.3191    0.8435    0.4631      2857
#
#     accuracy                         0.8757     44961
#    macro avg     0.6536    0.8607    0.6964     44961
# weighted avg     0.9455    0.8757    0.9001     44961
