# %%
# Import packages and modules
import numpy  as np
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow_decision_forests as tfdf

from sklearn.model_selection import train_test_split
# Out:
# 2026-07-04 09:11:52.742024: I tensorflow/core/util/port.cc:113] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2026-07-04 09:11:52.781744: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2026-07-04 09:11:57.098817: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
# Check the version of TensorFlow Decision Forests
print("Found TensorFlow Decision Forests v" + tfdf.__version__)
# Out:
# Found TensorFlow Decision Forests v1.9.1

# %%
datasetPath = 'dataset/firstorder/kernel5-radius5/dataset.csv'

# %%
# Parameters
datasetPath = "dataset/glszm/kernel5-radius5/500.dataset.csv"

# %%
# train/validation/test = 70/10/20
dataset = pd.read_csv(datasetPath)

train_data, temp_data = train_test_split(dataset, test_size=0.3, random_state=42)
validation_data, test_data = train_test_split(temp_data, test_size=2/3, random_state=42)

# %%
from sklearn.utils.class_weight import compute_class_weight

# tinh class weight tren tap train
classes = np.array([0, 1])
weights = compute_class_weight(class_weight="balanced", classes=classes, y=train_data["label"])
class_weight = {0: weights[0], 1: weights[1]}

# gan sample_weight cho tung dong
train_data["sample_weight"] = train_data["label"].map(class_weight)
validation_data["sample_weight"] = validation_data["label"].map(class_weight)
test_data["sample_weight"] = test_data["label"].map(class_weight)

# Convert the dataset into a TensorFlow dataset.
train_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    train_data, label="label", weight="sample_weight"
)         
val_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    validation_data, label="label", weight="sample_weight"
)
test_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    test_data, label="label", weight="sample_weight"
)
# Out:
# 2026-07-04 09:12:10.208018: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:984] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2026-07-04 09:12:10.209637: W tensorflow/core/common_runtime/gpu/gpu_device.cc:2251] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...

# %%
import keras

# %%
# %%time

# Train a Random Forest model.
model = tfdf.keras.RandomForestModel()

# Add evaluation metrics
model.compile(
    metrics=["accuracy"]
)
model.fit(x=train_ds)

# # Train a Gradient Boosted Trees model.
# model = tfdf.keras.GradientBoostedTreesModel(num_trees=1500)
# model.fit(train_ds)
# Out:
# Use /tmp/tmphw8_livk as temporary training directory
# Reading training dataset...
# Training dataset read in 0:00:05.723501. Found 395895 examples.
# Training model...
# [INFO 26-07-04 09:13:02.6200 UTC kernel.cc:1233] Loading model from path /tmp/tmphw8_livk/model/ with prefix 4511f2fd787c483c
# [INFO 26-07-04 09:13:05.1763 UTC decision_forest.cc:734] Model loaded with 300 root(s), 2048428 node(s), and 16 input feature(s).
# [INFO 26-07-04 09:13:05.1763 UTC abstract_model.cc:1362] Engine "RandomForestOptPred" built
# [INFO 26-07-04 09:13:05.1763 UTC kernel.cc:1061] Use fast generic engine
# Model trained in 0:00:49.383199
# Compiling model...
# Model compiled.
# CPU times: user 9min 6s, sys: 3.03 s, total: 9min 9s
# Wall time: 58.3 s

# %%
# Evaluate the model
evaluate = model.evaluate(val_ds, return_dict=True)
print()

for name, value in evaluate.items():
    print(f"{name}: {value:.4f}")
# Out:
# WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
#  1/57 [..............................] - ETA: 2:49 - loss: 0.0000e+00 - accuracy: 0.9060
#  3/57 [>.............................] - ETA: 2s - loss: 0.0000e+00 - accuracy: 0.9020
#  5/57 [=>............................] - ETA: 2s - loss: 0.0000e+00 - accuracy: 0.9014
#  7/57 [==>...........................] - ETA: 2s - loss: 0.0000e+00 - accuracy: 0.9000
#  9/57 [===>..........................] - ETA: 2s - loss: 0.0000e+00 - accuracy: 0.8982
# 11/57 [====>.........................] - ETA: 1s - loss: 0.0000e+00 - accuracy: 0.8978
# 13/57 [=====>........................] - ETA: 1s - loss: 0.0000e+00 - accuracy: 0.8975
# 15/57 [======>.......................] - ETA: 1s - loss: 0.0000e+00 - accuracy: 0.8974
# 16/57 [=======>......................] - ETA: 1s - loss: 0.0000e+00 - accuracy: 0.8979
# 17/57 [=======>......................] - ETA: 1s - loss: 0.0000e+00 - accuracy: 0.8978
# 19/57 [=========>....................] - ETA: 1s - loss: 0.0000e+00 - accuracy: 0.8978
# 20/57 [=========>....................] - ETA: 1s - loss: 0.0000e+00 - accuracy: 0.8977
# 22/57 [==========>...................] - ETA: 1s - loss: 0.0000e+00 - accuracy: 0.8984
# 24/57 [===========>..................] - ETA: 1s - loss: 0.0000e+00 - accuracy: 0.8987
# 26/57 [============>.................] - ETA: 1s - loss: 0.0000e+00 - accuracy: 0.8983
# 28/57 [=============>................] - ETA: 1s - loss: 0.0000e+00 - accuracy: 0.8974
# 30/57 [==============>...............] - ETA: 1s - loss: 0.0000e+00 - accuracy: 0.8975
# 32/57 [===============>..............] - ETA: 1s - loss: 0.0000e+00 - accuracy: 0.8978
# 34/57 [================>.............] - ETA: 1s - loss: 0.0000e+00 - accuracy: 0.8980
# 36/57 [=================>............] - ETA: 0s - loss: 0.0000e+00 - accuracy: 0.8980
# 38/57 [===================>..........] - ETA: 0s - loss: 0.0000e+00 - accuracy: 0.8981
# 39/57 [===================>..........] - ETA: 0s - loss: 0.0000e+00 - accuracy: 0.8980
# 41/57 [====================>.........] - ETA: 0s - loss: 0.0000e+00 - accuracy: 0.8983
# 43/57 [=====================>........] - ETA: 0s - loss: 0.0000e+00 - accuracy: 0.8993
# 45/57 [======================>.......] - ETA: 0s - loss: 0.0000e+00 - accuracy: 0.8989
# 47/57 [=======================>......] - ETA: 0s - loss: 0.0000e+00 - accuracy: 0.8984
# 49/57 [========================>.....] - ETA: 0s - loss: 0.0000e+00 - accuracy: 0.8989
# 51/57 [=========================>....] - ETA: 0s - loss: 0.0000e+00 - accuracy: 0.8989
# 53/57 [==========================>...] - ETA: 0s - loss: 0.0000e+00 - accuracy: 0.8991
# 55/57 [===========================>..] - ETA: 0s - loss: 0.0000e+00 - accuracy: 0.8991
# 57/57 [==============================] - ETA: 0s - loss: 0.0000e+00 - accuracy: 0.8992
# 57/57 [==============================] - 6s 44ms/step - loss: 0.0000e+00 - accuracy: 0.8992
# loss: 0.0000
# accuracy: 0.8992

# %%
# Model Summary
model.summary()
# Out:
# Model: "random_forest_model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
# =================================================================
# Total params: 1 (1.00 Byte)
# Trainable params: 0 (0.00 Byte)
# Non-trainable params: 1 (1.00 Byte)
# _________________________________________________________________
# Type: "RANDOM_FOREST"
# Task: CLASSIFICATION
# Label: "__LABEL"
#
# Input Features (16):
# 	GrayLevelNonUniformity
# 	GrayLevelNonUniformityNormalized
# 	GrayLevelVariance
# 	HighGrayLevelZoneEmphasis
# 	LargeAreaEmphasis
# 	LargeAreaHighGrayLevelEmphasis
# 	LargeAreaLowGrayLevelEmphasis
# 	LowGrayLevelZoneEmphasis
# 	SizeZoneNonUniformity
# 	SizeZoneNonUniformityNormalized
# 	SmallAreaEmphasis
# 	SmallAreaHighGrayLevelEmphasis
# 	SmallAreaLowGrayLevelEmphasis
# 	ZoneEntropy
# 	ZonePercentage
# 	ZoneVariance
#
# Trained with weights
#
# Variable Importance: INV_MEAN_MIN_DEPTH:
#     1.        "HighGrayLevelZoneEmphasis"  0.200303 ################
#     2.           "GrayLevelNonUniformity"  0.152053 #########
#     3.    "LargeAreaLowGrayLevelEmphasis"  0.137541 #######
#     4.    "SmallAreaLowGrayLevelEmphasis"  0.137523 #######
#     5.   "LargeAreaHighGrayLevelEmphasis"  0.126905 ######
#     6.         "LowGrayLevelZoneEmphasis"  0.121117 #####
#     7.   "SmallAreaHighGrayLevelEmphasis"  0.103779 ###
#     8.  "SizeZoneNonUniformityNormalized"  0.094374 ##
#     9.                "GrayLevelVariance"  0.092153 #
#    10.                "SmallAreaEmphasis"  0.091196 #
#    11.                      "ZoneEntropy"  0.089577 #
#    12.            "SizeZoneNonUniformity"  0.087639 #
#    13. "GrayLevelNonUniformityNormalized"  0.085659
#    14.                     "ZoneVariance"  0.083677
#    15.                   "ZonePercentage"  0.081136
#    16.                "LargeAreaEmphasis"  0.078718
#
# Variable Importance: NUM_AS_ROOT:
#     1.        "HighGrayLevelZoneEmphasis" 93.000000 ################
#     2.    "LargeAreaLowGrayLevelEmphasis" 71.000000 ############
#     3.    "SmallAreaLowGrayLevelEmphasis" 51.000000 ########
#     4.         "LowGrayLevelZoneEmphasis" 35.000000 #####
#     5.   "SmallAreaHighGrayLevelEmphasis" 20.000000 ###
#     6.                "GrayLevelVariance" 14.000000 ##
#     7.   "LargeAreaHighGrayLevelEmphasis"  9.000000 #
#     8.                      "ZoneEntropy"  4.000000
#     9. "GrayLevelNonUniformityNormalized"  2.000000
#    10.                     "ZoneVariance"  1.000000
#
# Variable Importance: NUM_NODES:
#     1.   "LargeAreaHighGrayLevelEmphasis" 83917.000000 ################
#     2.    "LargeAreaLowGrayLevelEmphasis" 81412.000000 ##############
#     3.           "GrayLevelNonUniformity" 78183.000000 #############
#     4.         "LowGrayLevelZoneEmphasis" 66360.000000 ########
#     5.                     "ZoneVariance" 66091.000000 #######
#     6.        "HighGrayLevelZoneEmphasis" 65716.000000 #######
#     7.                      "ZoneEntropy" 65347.000000 #######
#     8.                "GrayLevelVariance" 64587.000000 #######
#     9.    "SmallAreaLowGrayLevelEmphasis" 62001.000000 ######
#    10. "GrayLevelNonUniformityNormalized" 61394.000000 #####
#    11.   "SmallAreaHighGrayLevelEmphasis" 61103.000000 #####
#    12.                "LargeAreaEmphasis" 58564.000000 ####
#    13.  "SizeZoneNonUniformityNormalized" 53968.000000 ##
#    14.                "SmallAreaEmphasis" 53680.000000 ##
#    15.            "SizeZoneNonUniformity" 53387.000000 ##
#    16.                   "ZonePercentage" 48354.000000
#
# Variable Importance: SUM_SCORE:
#     1.        "HighGrayLevelZoneEmphasis" 8851071.632028 ################
#     2.           "GrayLevelNonUniformity" 7011231.906974 ############
#     3.    "LargeAreaLowGrayLevelEmphasis" 5887198.905812 #########
#     4.    "SmallAreaLowGrayLevelEmphasis" 5594794.963282 ########
#     5.   "LargeAreaHighGrayLevelEmphasis" 5025031.658630 #######
#     6.         "LowGrayLevelZoneEmphasis" 4628117.412594 ######
#     7.   "SmallAreaHighGrayLevelEmphasis" 3418261.886635 ####
#     8.  "SizeZoneNonUniformityNormalized" 2661128.772184 ##
#     9.                      "ZoneEntropy" 2620978.197232 ##
#    10.                "SmallAreaEmphasis" 2411706.740420 ##
#    11.                "GrayLevelVariance" 2339363.960463 #
#    12. "GrayLevelNonUniformityNormalized" 2051726.356583 #
#    13.            "SizeZoneNonUniformity" 1966467.780666 #
#    14.                     "ZoneVariance" 1917214.151611
#    15.                "LargeAreaEmphasis" 1494877.454681
#    16.                   "ZonePercentage" 1476788.885712
#
#
#
# Winner takes all: true
# Out-of-bag evaluation: accuracy:0.844417 logloss:0.52664
# Number of trees: 300
# Total number of nodes: 2048428
#
# Number of nodes by tree:
# Count: 300 Average: 6828.09 StdDev: 416.828
# Min: 5869 Max: 7995 Ignored: 0
# ----------------------------------------------
# [ 5869, 5975)  3   1.00%   1.00% #
# [ 5975, 6081)  7   2.33%   3.33% ##
# [ 6081, 6188) 13   4.33%   7.67% ####
# [ 6188, 6294)  7   2.33%  10.00% ##
# [ 6294, 6400) 18   6.00%  16.00% ######
# [ 6400, 6507) 25   8.33%  24.33% ########
# [ 6507, 6613) 24   8.00%  32.33% ########
# [ 6613, 6719) 22   7.33%  39.67% #######
# [ 6719, 6826) 32  10.67%  50.33% ##########
# [ 6826, 6932) 30  10.00%  60.33% #########
# [ 6932, 7038) 23   7.67%  68.00% #######
# [ 7038, 7145) 20   6.67%  74.67% ######
# [ 7145, 7251) 24   8.00%  82.67% ########
# [ 7251, 7357) 20   6.67%  89.33% ######
# [ 7357, 7464) 16   5.33%  94.67% #####
# [ 7464, 7570)  5   1.67%  96.33% ##
# [ 7570, 7676)  6   2.00%  98.33% ##
# [ 7676, 7783)  2   0.67%  99.00% #
# [ 7783, 7889)  1   0.33%  99.33%
# [ 7889, 7995]  2   0.67% 100.00% #
#
# Depth by leafs:
# Count: 1.02436e+06 Average: 13.4493 StdDev: 1.82242
# Min: 3 Max: 15 Ignored: 0
# ----------------------------------------------
# [  3,  4)      1   0.00%   0.00%
# [  4,  5)     11   0.00%   0.00%
# [  5,  6)    199   0.02%   0.02%
# [  6,  7)   1217   0.12%   0.14%
# [  7,  8)   4409   0.43%   0.57%
# [  8,  9)  11260   1.10%   1.67%
# [  9, 10)  24218   2.36%   4.03% #
# [ 10, 11)  45029   4.40%   8.43% #
# [ 11, 12)  73513   7.18%  15.61% ##
# [ 12, 13) 108145  10.56%  26.16% ###
# [ 13, 14) 145976  14.25%  40.41% ###
# [ 14, 15) 180374  17.61%  58.02% ####
# [ 15, 15] 430012  41.98% 100.00% ##########
#
# Number of training obs by leaf:
# Count: 1.02436e+06 Average: 115.944 StdDev: 498.65
# Min: 5 Max: 31954 Ignored: 0
# ----------------------------------------------
# [     5,  1602) 1.01286e+06  98.88%  98.88% ##########
# [  1602,  3200)        7498   0.73%  99.61%
# [  3200,  4797)        2023   0.20%  99.81%
# [  4797,  6395)         814   0.08%  99.89%
# [  6395,  7992)         398   0.04%  99.92%
# [  7992,  9590)         272   0.03%  99.95%
# [  9590, 11187)         144   0.01%  99.97%
# [ 11187, 12785)         133   0.01%  99.98%
# [ 12785, 14382)          85   0.01%  99.99%
# [ 14382, 15980)          44   0.00%  99.99%
# [ 15980, 17577)          35   0.00%  99.99%
# [ 17577, 19175)          17   0.00% 100.00%
# [ 19175, 20772)          13   0.00% 100.00%
# [ 20772, 22370)          10   0.00% 100.00%
# [ 22370, 23967)           5   0.00% 100.00%
# [ 23967, 25565)           5   0.00% 100.00%
# [ 25565, 27162)           3   0.00% 100.00%
# [ 27162, 28760)           3   0.00% 100.00%
# [ 28760, 30357)           0   0.00% 100.00%
# [ 30357, 31954]           1   0.00% 100.00%
#
# Attribute in nodes:
# 	83917 : LargeAreaHighGrayLevelEmphasis [NUMERICAL]
# 	81412 : LargeAreaLowGrayLevelEmphasis [NUMERICAL]
# 	78183 : GrayLevelNonUniformity [NUMERICAL]
# 	66360 : LowGrayLevelZoneEmphasis [NUMERICAL]
# 	66091 : ZoneVariance [NUMERICAL]
# 	65716 : HighGrayLevelZoneEmphasis [NUMERICAL]
# 	65347 : ZoneEntropy [NUMERICAL]
# 	64587 : GrayLevelVariance [NUMERICAL]
# 	62001 : SmallAreaLowGrayLevelEmphasis [NUMERICAL]
# 	61394 : GrayLevelNonUniformityNormalized [NUMERICAL]
# 	61103 : SmallAreaHighGrayLevelEmphasis [NUMERICAL]
# 	58564 : LargeAreaEmphasis [NUMERICAL]
# 	53968 : SizeZoneNonUniformityNormalized [NUMERICAL]
# 	53680 : SmallAreaEmphasis [NUMERICAL]
# 	53387 : SizeZoneNonUniformity [NUMERICAL]
# 	48354 : ZonePercentage [NUMERICAL]
#
# Attribute in nodes with depth <= 0:
# 	93 : HighGrayLevelZoneEmphasis [NUMERICAL]
# 	71 : LargeAreaLowGrayLevelEmphasis [NUMERICAL]
# 	51 : SmallAreaLowGrayLevelEmphasis [NUMERICAL]
# 	35 : LowGrayLevelZoneEmphasis [NUMERICAL]
# 	20 : SmallAreaHighGrayLevelEmphasis [NUMERICAL]
# 	14 : GrayLevelVariance [NUMERICAL]
# 	9 : LargeAreaHighGrayLevelEmphasis [NUMERICAL]
# 	4 : ZoneEntropy [NUMERICAL]
# 	2 : GrayLevelNonUniformityNormalized [NUMERICAL]
# 	1 : ZoneVariance [NUMERICAL]
#
# Attribute in nodes with depth <= 1:
# 	201 : HighGrayLevelZoneEmphasis [NUMERICAL]
# 	151 : SmallAreaLowGrayLevelEmphasis [NUMERICAL]
# 	104 : LargeAreaLowGrayLevelEmphasis [NUMERICAL]
# 	99 : LargeAreaHighGrayLevelEmphasis [NUMERICAL]
# 	88 : LowGrayLevelZoneEmphasis [NUMERICAL]
# 	84 : GrayLevelNonUniformity [NUMERICAL]
# 	45 : SmallAreaHighGrayLevelEmphasis [NUMERICAL]
# 	37 : GrayLevelVariance [NUMERICAL]
# 	20 : SizeZoneNonUniformity [NUMERICAL]
# 	18 : SizeZoneNonUniformityNormalized [NUMERICAL]
# 	17 : GrayLevelNonUniformityNormalized [NUMERICAL]
# 	12 : SmallAreaEmphasis [NUMERICAL]
# 	10 : ZonePercentage [NUMERICAL]
# 	8 : ZoneEntropy [NUMERICAL]
# 	4 : ZoneVariance [NUMERICAL]
# 	2 : LargeAreaEmphasis [NUMERICAL]
#
# Attribute in nodes with depth <= 2:
# 	423 : HighGrayLevelZoneEmphasis [NUMERICAL]
# 	290 : GrayLevelNonUniformity [NUMERICAL]
# 	264 : SmallAreaLowGrayLevelEmphasis [NUMERICAL]
# 	184 : LowGrayLevelZoneEmphasis [NUMERICAL]
# 	172 : LargeAreaHighGrayLevelEmphasis [NUMERICAL]
# 	165 : LargeAreaLowGrayLevelEmphasis [NUMERICAL]
# 	122 : SmallAreaHighGrayLevelEmphasis [NUMERICAL]
# 	97 : GrayLevelVariance [NUMERICAL]
# 	82 : SizeZoneNonUniformityNormalized [NUMERICAL]
# 	73 : SizeZoneNonUniformity [NUMERICAL]
# 	63 : SmallAreaEmphasis [NUMERICAL]
# 	56 : ZoneEntropy [NUMERICAL]
# 	50 : GrayLevelNonUniformityNormalized [NUMERICAL]
# 	33 : ZonePercentage [NUMERICAL]
# 	18 : ZoneVariance [NUMERICAL]
# 	8 : LargeAreaEmphasis [NUMERICAL]
#
# Attribute in nodes with depth <= 3:
# 	743 : HighGrayLevelZoneEmphasis [NUMERICAL]
# 	690 : GrayLevelNonUniformity [NUMERICAL]
# 	445 : SmallAreaLowGrayLevelEmphasis [NUMERICAL]
# 	371 : LargeAreaLowGrayLevelEmphasis [NUMERICAL]
# 	367 : LargeAreaHighGrayLevelEmphasis [NUMERICAL]
# 	365 : LowGrayLevelZoneEmphasis [NUMERICAL]
# 	242 : GrayLevelVariance [NUMERICAL]
# 	235 : SmallAreaHighGrayLevelEmphasis [NUMERICAL]
# 	199 : SizeZoneNonUniformity [NUMERICAL]
# 	194 : SizeZoneNonUniformityNormalized [NUMERICAL]
# 	173 : SmallAreaEmphasis [NUMERICAL]
# 	142 : ZoneEntropy [NUMERICAL]
# 	124 : GrayLevelNonUniformityNormalized [NUMERICAL]
# 	90 : ZonePercentage [NUMERICAL]
# 	74 : ZoneVariance [NUMERICAL]
# 	45 : LargeAreaEmphasis [NUMERICAL]
#
# Attribute in nodes with depth <= 5:
# 	2662 : GrayLevelNonUniformity [NUMERICAL]
# 	2201 : HighGrayLevelZoneEmphasis [NUMERICAL]
# 	1651 : LargeAreaLowGrayLevelEmphasis [NUMERICAL]
# 	1638 : LargeAreaHighGrayLevelEmphasis [NUMERICAL]
# 	1374 : LowGrayLevelZoneEmphasis [NUMERICAL]
# 	1280 : SmallAreaLowGrayLevelEmphasis [NUMERICAL]
# 	1062 : GrayLevelVariance [NUMERICAL]
# 	1030 : SmallAreaHighGrayLevelEmphasis [NUMERICAL]
# 	914 : ZoneEntropy [NUMERICAL]
# 	798 : SizeZoneNonUniformity [NUMERICAL]
# 	792 : ZoneVariance [NUMERICAL]
# 	758 : SizeZoneNonUniformityNormalized [NUMERICAL]
# 	716 : SmallAreaEmphasis [NUMERICAL]
# 	708 : GrayLevelNonUniformityNormalized [NUMERICAL]
# 	571 : ZonePercentage [NUMERICAL]
# 	506 : LargeAreaEmphasis [NUMERICAL]
#
# Condition type in nodes:
# 	1024064 : HigherCondition
# Condition type in nodes with depth <= 0:
# 	300 : HigherCondition
# Condition type in nodes with depth <= 1:
# 	900 : HigherCondition
# Condition type in nodes with depth <= 2:
# 	2100 : HigherCondition
# Condition type in nodes with depth <= 3:
# 	4499 : HigherCondition
# Condition type in nodes with depth <= 5:
# 	18661 : HigherCondition
# Node format: NOT_SET
#
# Training OOB:
# 	trees: 1, Out-of-bag evaluation: accuracy:0.802273 logloss:7.12679
# 	trees: 11, Out-of-bag evaluation: accuracy:0.817518 logloss:2.85215
# 	trees: 21, Out-of-bag evaluation: accuracy:0.830135 logloss:1.77129
# 	trees: 31, Out-of-bag evaluation: accuracy:0.835228 logloss:1.38373
# 	trees: 41, Out-of-bag evaluation: accuracy:0.837603 logloss:1.16323
# 	trees: 51, Out-of-bag evaluation: accuracy:0.839304 logloss:1.02476
# 	trees: 61, Out-of-bag evaluation: accuracy:0.84009 logloss:0.932208
# 	trees: 71, Out-of-bag evaluation: accuracy:0.841089 logloss:0.861137
# 	trees: 81, Out-of-bag evaluation: accuracy:0.841314 logloss:0.806094
# 	trees: 91, Out-of-bag evaluation: accuracy:0.841816 logloss:0.777643
# 	trees: 101, Out-of-bag evaluation: accuracy:0.842538 logloss:0.744304
# 	trees: 111, Out-of-bag evaluation: accuracy:0.842454 logloss:0.710874
# 	trees: 121, Out-of-bag evaluation: accuracy:0.842438 logloss:0.684609
# 	trees: 131, Out-of-bag evaluation: accuracy:0.842492 logloss:0.665949
# 	trees: 141, Out-of-bag evaluation: accuracy:0.842753 logloss:0.651887
# 	trees: 151, Out-of-bag evaluation: accuracy:0.842504 logloss:0.63812
# 	trees: 161, Out-of-bag evaluation: accuracy:0.843059 logloss:0.621271
# 	trees: 171, Out-of-bag evaluation: accuracy:0.843363 logloss:0.611855
# 	trees: 181, Out-of-bag evaluation: accuracy:0.843822 logloss:0.598303
# 	trees: 191, Out-of-bag evaluation: accuracy:0.843661 logloss:0.591517
# 	trees: 201, Out-of-bag evaluation: accuracy:0.84428 logloss:0.584142
# 	trees: 211, Out-of-bag evaluation: accuracy:0.84416 logloss:0.574102
# 	trees: 221, Out-of-bag evaluation: accuracy:0.844085 logloss:0.56654
# 	trees: 231, Out-of-bag evaluation: accuracy:0.844432 logloss:0.559675
# 	trees: 241, Out-of-bag evaluation: accuracy:0.844781 logloss:0.55398
# 	trees: 251, Out-of-bag evaluation: accuracy:0.844476 logloss:0.549334
# 	trees: 261, Out-of-bag evaluation: accuracy:0.844449 logloss:0.543956
# 	trees: 271, Out-of-bag evaluation: accuracy:0.844332 logloss:0.5415
# 	trees: 281, Out-of-bag evaluation: accuracy:0.84449 logloss:0.534669
# 	trees: 291, Out-of-bag evaluation: accuracy:0.844385 logloss:0.529264
# 	trees: 300, Out-of-bag evaluation: accuracy:0.844417 logloss:0.52664

# %%
# Model features
model.make_inspector().features()
# Out:
# ["GrayLevelNonUniformity" (1; #0),
#  "GrayLevelNonUniformityNormalized" (1; #1),
#  "GrayLevelVariance" (1; #2),
#  "HighGrayLevelZoneEmphasis" (1; #3),
#  "LargeAreaEmphasis" (1; #4),
#  "LargeAreaHighGrayLevelEmphasis" (1; #5),
#  "LargeAreaLowGrayLevelEmphasis" (1; #6),
#  "LowGrayLevelZoneEmphasis" (1; #7),
#  "SizeZoneNonUniformity" (1; #8),
#  "SizeZoneNonUniformityNormalized" (1; #9),
#  "SmallAreaEmphasis" (1; #10),
#  "SmallAreaHighGrayLevelEmphasis" (1; #11),
#  "SmallAreaLowGrayLevelEmphasis" (1; #12),
#  "ZoneEntropy" (1; #13),
#  "ZonePercentage" (1; #14),
#  "ZoneVariance" (1; #15)]

# %%
# Feature importance
model.make_inspector().variable_importances()
# Out:
# {'INV_MEAN_MIN_DEPTH': [("HighGrayLevelZoneEmphasis" (1; #3),
#    0.2003025839143319),
#   ("GrayLevelNonUniformity" (1; #0), 0.15205342375288383),
#   ("LargeAreaLowGrayLevelEmphasis" (1; #6), 0.1375407845748544),
#   ("SmallAreaLowGrayLevelEmphasis" (1; #12), 0.1375227501271979),
#   ("LargeAreaHighGrayLevelEmphasis" (1; #5), 0.12690520107143072),
#   ("LowGrayLevelZoneEmphasis" (1; #7), 0.12111726294851596),
#   ("SmallAreaHighGrayLevelEmphasis" (1; #11), 0.10377937373531618),
#   ("SizeZoneNonUniformityNormalized" (1; #9), 0.09437354998104788),
#   ("GrayLevelVariance" (1; #2), 0.09215345929755032),
#   ("SmallAreaEmphasis" (1; #10), 0.0911957999959533),
#   ("ZoneEntropy" (1; #13), 0.08957673559569555),
#   ("SizeZoneNonUniformity" (1; #8), 0.08763892130185161),
#   ("GrayLevelNonUniformityNormalized" (1; #1), 0.08565913892618333),
#   ("ZoneVariance" (1; #15), 0.08367719913050678),
#   ("ZonePercentage" (1; #14), 0.08113646978410344),
#   ("LargeAreaEmphasis" (1; #4), 0.07871803435622125)],
#  'NUM_AS_ROOT': [("HighGrayLevelZoneEmphasis" (1; #3), 93.0),
#   ("LargeAreaLowGrayLevelEmphasis" (1; #6), 71.0),
#   ("SmallAreaLowGrayLevelEmphasis" (1; #12), 51.0),
#   ("LowGrayLevelZoneEmphasis" (1; #7), 35.0),
#   ("SmallAreaHighGrayLevelEmphasis" (1; #11), 20.0),
#   ("GrayLevelVariance" (1; #2), 14.0),
#   ("LargeAreaHighGrayLevelEmphasis" (1; #5), 9.0),
#   ("ZoneEntropy" (1; #13), 4.0),
#   ("GrayLevelNonUniformityNormalized" (1; #1), 2.0),
#   ("ZoneVariance" (1; #15), 1.0)],
#  'SUM_SCORE': [("HighGrayLevelZoneEmphasis" (1; #3), 8851071.632028159),
#   ("GrayLevelNonUniformity" (1; #0), 7011231.906974117),
#   ("LargeAreaLowGrayLevelEmphasis" (1; #6), 5887198.905811778),
#   ("SmallAreaLowGrayLevelEmphasis" (1; #12), 5594794.963282342),
#   ("LargeAreaHighGrayLevelEmphasis" (1; #5), 5025031.658630254),
#   ("LowGrayLevelZoneEmphasis" (1; #7), 4628117.412594216),
#   ("SmallAreaHighGrayLevelEmphasis" (1; #11), 3418261.886635315),
#   ("SizeZoneNonUniformityNormalized" (1; #9), 2661128.772184395),
#   ("ZoneEntropy" (1; #13), 2620978.197231852),
#   ("SmallAreaEmphasis" (1; #10), 2411706.7404200644),
#   ("GrayLevelVariance" (1; #2), 2339363.960463283),
#   ("GrayLevelNonUniformityNormalized" (1; #1), 2051726.3565825538),
#   ("SizeZoneNonUniformity" (1; #8), 1966467.7806661837),
#   ("ZoneVariance" (1; #15), 1917214.1516107225),
#   ("LargeAreaEmphasis" (1; #4), 1494877.454680595),
#   ("ZonePercentage" (1; #14), 1476788.885712023)],
#  'NUM_NODES': [("LargeAreaHighGrayLevelEmphasis" (1; #5), 83917.0),
#   ("LargeAreaLowGrayLevelEmphasis" (1; #6), 81412.0),
#   ("GrayLevelNonUniformity" (1; #0), 78183.0),
#   ("LowGrayLevelZoneEmphasis" (1; #7), 66360.0),
#   ("ZoneVariance" (1; #15), 66091.0),
#   ("HighGrayLevelZoneEmphasis" (1; #3), 65716.0),
#   ("ZoneEntropy" (1; #13), 65347.0),
#   ("GrayLevelVariance" (1; #2), 64587.0),
#   ("SmallAreaLowGrayLevelEmphasis" (1; #12), 62001.0),
#   ("GrayLevelNonUniformityNormalized" (1; #1), 61394.0),
#   ("SmallAreaHighGrayLevelEmphasis" (1; #11), 61103.0),
#   ("LargeAreaEmphasis" (1; #4), 58564.0),
#   ("SizeZoneNonUniformityNormalized" (1; #9), 53968.0),
#   ("SmallAreaEmphasis" (1; #10), 53680.0),
#   ("SizeZoneNonUniformity" (1; #8), 53387.0),
#   ("ZonePercentage" (1; #14), 48354.0)]}

# %%
# Model self evaluation
model.make_inspector().evaluation()
# Out:
# Evaluation(num_examples=395895, accuracy=0.8444168235282193, loss=0.5266400352844727, rmse=None, ndcg=None, aucs=None, auuc=None, qini=None)

# %%
logs = model.make_inspector().training_logs()

plt.figure(figsize=(12, 4))
plt.subplot(1, 2, 1)
plt.plot([log.num_trees for log in logs], [log.evaluation.accuracy for log in logs])
plt.xlabel("Number of trees")
plt.ylabel("Accuracy (out-of-bag)")
plt.subplot(1, 2, 2)
plt.plot([log.num_trees for log in logs], [log.evaluation.loss for log in logs])
plt.xlabel("Number of trees")
plt.ylabel("Logloss (out-of-bag)")
plt.show()

# %% [markdown]
# Calculate the score of our hold-out validation dataset

# %%
predictions = model.predict(val_ds)
y_true      = validation_data["label"]

from sklearn.metrics import roc_auc_score
ROC_AUC = roc_auc_score(y_true, predictions)
print("The ROC AUC score is %.5f" % ROC_AUC )
# Out:
#  1/57 [..............................] - ETA: 6s
#  2/57 [>.............................] - ETA: 42s
#  4/57 [=>............................] - ETA: 15s
#  6/57 [==>...........................] - ETA: 19s
#  8/57 [===>..........................] - ETA: 14s
# 10/57 [====>.........................] - ETA: 11s
# 12/57 [=====>........................] - ETA: 9s
# 14/57 [======>.......................] - ETA: 7s
# 16/57 [=======>......................] - ETA: 6s
# 18/57 [========>.....................] - ETA: 5s
# 20/57 [=========>....................] - ETA: 4s
# 22/57 [==========>...................] - ETA: 4s
# 24/57 [===========>..................] - ETA: 3s
# 26/57 [============>.................] - ETA: 3s
# 28/57 [=============>................] - ETA: 3s
# 30/57 [==============>...............] - ETA: 2s
# 32/57 [===============>..............] - ETA: 2s
# 34/57 [================>.............] - ETA: 2s
# 36/57 [=================>............] - ETA: 1s
# 38/57 [===================>..........] - ETA: 1s
# 40/57 [====================>.........] - ETA: 1s
# 41/57 [====================>.........] - ETA: 1s
# 43/57 [=====================>........] - ETA: 1s
# 45/57 [======================>.......] - ETA: 0s
# 47/57 [=======================>......] - ETA: 0s
# 49/57 [========================>.....] - ETA: 0s
# 51/57 [=========================>....] - ETA: 0s
# 52/57 [==========================>...] - ETA: 0s
# 54/57 [===========================>..] - ETA: 0s
# 55/57 [===========================>..] - ETA: 0s
# 57/57 [==============================] - ETA: 0s
# 57/57 [==============================] - 4s 75ms/step
# The ROC AUC score is 0.92997

# %%
# Compute binary classification metrics with sklearn
import numpy as np
from sklearn.metrics import (
    accuracy_score,
    precision_score,
    recall_score,
    f1_score,
    roc_auc_score,
    average_precision_score,
    confusion_matrix,
    classification_report,
    matthews_corrcoef,
    log_loss,
    brier_score_loss,
)

# Get predictions (probabilities or class labels)
preds = model.predict(test_ds)
# If model outputs probabilities, convert to labels by threshold 0.5
if preds.ndim == 2:
    # For TFDF classification, preds may be class probabilities with shape (N, 2)
    if preds.shape[1] == 2:
        pos_probs = preds[:, 1]
    else:
        # If single-probability column (positive class)
        pos_probs = preds[:, -1]
    y_pred = (pos_probs >= 0.5).astype(int)
else:
    # Already class labels
    y_pred = preds.astype(int)
    pos_probs = None

# Ground truth labels (must be 0/1 integers)
y_true = test_data["label"].astype(int).to_numpy()

# Core metrics
metrics = {}
metrics["accuracy"] = accuracy_score(y_true, y_pred)
metrics["precision"] = precision_score(y_true, y_pred, zero_division=0)
metrics["recall"] = recall_score(y_true, y_pred, zero_division=0)
metrics["f1"] = f1_score(y_true, y_pred, zero_division=0)
metrics["mcc"] = matthews_corrcoef(y_true, y_pred)

# Probabilistic metrics (only if we have probabilities)
if pos_probs is not None:
    metrics["roc_auc"] = roc_auc_score(y_true, pos_probs)
    metrics["pr_auc"] = average_precision_score(y_true, pos_probs)
    metrics["log_loss"] = log_loss(y_true, pos_probs, labels=[0,1])
    metrics["brier_score"] = brier_score_loss(y_true, pos_probs)

# Confusion matrix and detailed report
cm = confusion_matrix(y_true, y_pred, labels=[0,1])
report = classification_report(y_true, y_pred, digits=4)

print("Sklearn binary metrics:")
for k, v in metrics.items():
    print(f"{k}: {v:.4f}")
print("\nConfusion matrix:\n", cm)
print("\nClassification report:\n", report)
# Out:
#   1/114 [..............................] - ETA: 11s
#   3/114 [..............................] - ETA: 4s
#   5/114 [>.............................] - ETA: 4s
#   7/114 [>.............................] - ETA: 4s
#   9/114 [=>............................] - ETA: 4s
#  11/114 [=>............................] - ETA: 4s
#  13/114 [==>...........................] - ETA: 4s
#  15/114 [==>...........................] - ETA: 4s
#  17/114 [===>..........................] - ETA: 4s
#  19/114 [====>.........................] - ETA: 4s
#  21/114 [====>.........................] - ETA: 3s
#  23/114 [=====>........................] - ETA: 3s
#  25/114 [=====>........................] - ETA: 3s
#  27/114 [======>.......................] - ETA: 3s
#  28/114 [======>.......................] - ETA: 3s
#  30/114 [======>.......................] - ETA: 3s
#  32/114 [=======>......................] - ETA: 3s
#  34/114 [=======>......................] - ETA: 3s
#  36/114 [========>.....................] - ETA: 3s
#  38/114 [=========>....................] - ETA: 3s
#  40/114 [=========>....................] - ETA: 3s
#  42/114 [==========>...................] - ETA: 3s
#  44/114 [==========>...................] - ETA: 3s
#  45/114 [==========>...................] - ETA: 3s
#  47/114 [===========>..................] - ETA: 2s
#  49/114 [===========>..................] - ETA: 2s
#  51/114 [============>.................] - ETA: 2s
#  53/114 [============>.................] - ETA: 2s
#  55/114 [=============>................] - ETA: 2s
#  57/114 [==============>...............] - ETA: 2s
#  59/114 [==============>...............] - ETA: 2s
#  61/114 [===============>..............] - ETA: 2s
#  63/114 [===============>..............] - ETA: 2s
#  65/114 [================>.............] - ETA: 2s
#  67/114 [================>.............] - ETA: 2s
#  69/114 [=================>............] - ETA: 1s
#  70/114 [=================>............] - ETA: 1s
#  72/114 [=================>............] - ETA: 1s
#  74/114 [==================>...........] - ETA: 1s
#  76/114 [===================>..........] - ETA: 1s
#  78/114 [===================>..........] - ETA: 1s
#  80/114 [====================>.........] - ETA: 1s
#  81/114 [====================>.........] - ETA: 1s
#  83/114 [====================>.........] - ETA: 1s
#  85/114 [=====================>........] - ETA: 1s
#  87/114 [=====================>........] - ETA: 1s
#  89/114 [======================>.......] - ETA: 1s
#  91/114 [======================>.......] - ETA: 1s
#  93/114 [=======================>......] - ETA: 0s
#  95/114 [========================>.....] - ETA: 0s
#  97/114 [========================>.....] - ETA: 0s
#  99/114 [=========================>....] - ETA: 0s
# 101/114 [=========================>....] - ETA: 0s
# 103/114 [==========================>...] - ETA: 0s
# 105/114 [==========================>...] - ETA: 0s
# 107/114 [===========================>..] - ETA: 0s
# 109/114 [===========================>..] - ETA: 0s
# 111/114 [============================>.] - ETA: 0s
# 113/114 [============================>.] - ETA: 0s
# 114/114 [==============================] - 5s 44ms/step
# Sklearn binary metrics:
# accuracy: 0.8996
# precision: 0.3693
# recall: 0.7826
# f1: 0.5018
# mcc: 0.4937
# roc_auc: 0.9307
# pr_auc: 0.5418
# log_loss: 0.2598
# brier_score: 0.0737
#
# Confusion matrix:
#  [[96043  9765]
#  [ 1588  5718]]
#
# Classification report:
#                precision    recall  f1-score   support
#
#            0     0.9837    0.9077    0.9442    105808
#            1     0.3693    0.7826    0.5018      7306
#
#     accuracy                         0.8996    113114
#    macro avg     0.6765    0.8452    0.7230    113114
# weighted avg     0.9440    0.8996    0.9156    113114
