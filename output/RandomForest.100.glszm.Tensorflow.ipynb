# %%
# Import packages and modules
import numpy  as np
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow_decision_forests as tfdf

from sklearn.model_selection import train_test_split
# Out:
# 2026-07-04 09:07:43.191903: I tensorflow/core/util/port.cc:113] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2026-07-04 09:07:43.236035: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2026-07-04 09:07:47.516191: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
# Check the version of TensorFlow Decision Forests
print("Found TensorFlow Decision Forests v" + tfdf.__version__)
# Out:
# Found TensorFlow Decision Forests v1.9.1

# %%
datasetPath = 'dataset/firstorder/kernel5-radius5/dataset.csv'

# %%
# Parameters
datasetPath = "dataset/glszm/kernel5-radius5/100.dataset.csv"

# %%
# train/validation/test = 70/10/20
dataset = pd.read_csv(datasetPath)

train_data, temp_data = train_test_split(dataset, test_size=0.3, random_state=42)
validation_data, test_data = train_test_split(temp_data, test_size=2/3, random_state=42)

# %%
from sklearn.utils.class_weight import compute_class_weight

# tinh class weight tren tap train
classes = np.array([0, 1])
weights = compute_class_weight(class_weight="balanced", classes=classes, y=train_data["label"])
class_weight = {0: weights[0], 1: weights[1]}

# gan sample_weight cho tung dong
train_data["sample_weight"] = train_data["label"].map(class_weight)
validation_data["sample_weight"] = validation_data["label"].map(class_weight)
test_data["sample_weight"] = test_data["label"].map(class_weight)

# Convert the dataset into a TensorFlow dataset.
train_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    train_data, label="label", weight="sample_weight"
)         
val_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    validation_data, label="label", weight="sample_weight"
)
test_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    test_data, label="label", weight="sample_weight"
)
# Out:
# 2026-07-04 09:08:01.220883: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:984] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2026-07-04 09:08:01.222719: W tensorflow/core/common_runtime/gpu/gpu_device.cc:2251] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...

# %%
import keras

# %%
# %%time

# Train a Random Forest model.
model = tfdf.keras.RandomForestModel()

# Add evaluation metrics
model.compile(
    metrics=["accuracy"]
)
model.fit(x=train_ds)

# # Train a Gradient Boosted Trees model.
# model = tfdf.keras.GradientBoostedTreesModel(num_trees=1500)
# model.fit(train_ds)
# Out:
# Use /tmp/tmpbt44vfll as temporary training directory
# Reading training dataset...
# Training dataset read in 0:00:02.779033. Found 78712 examples.
# Training model...
# [INFO 26-07-04 09:08:10.8403 UTC kernel.cc:1233] Loading model from path /tmp/tmpbt44vfll/model/ with prefix a9630ffc62174580
# Model trained in 0:00:07.603141
# Compiling model...
# [INFO 26-07-04 09:08:11.6494 UTC decision_forest.cc:734] Model loaded with 300 root(s), 685112 node(s), and 16 input feature(s).
# [INFO 26-07-04 09:08:11.6495 UTC abstract_model.cc:1362] Engine "RandomForestOptPred" built
# [INFO 26-07-04 09:08:11.6495 UTC kernel.cc:1061] Use fast generic engine
# Model compiled.
# CPU times: user 1min 23s, sys: 900 ms, total: 1min 24s
# Wall time: 13.5 s

# %%
# Evaluate the model
evaluate = model.evaluate(val_ds, return_dict=True)
print()

for name, value in evaluate.items():
    print(f"{name}: {value:.4f}")
# Out:
# WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
#  1/12 [=>............................] - ETA: 32s - loss: 0.0000e+00 - accuracy: 0.9440
#  3/12 [======>.......................] - ETA: 0s - loss: 0.0000e+00 - accuracy: 0.9427
#  5/12 [===========>..................] - ETA: 0s - loss: 0.0000e+00 - accuracy: 0.9386
#  7/12 [================>.............] - ETA: 0s - loss: 0.0000e+00 - accuracy: 0.9411
#  9/12 [=====================>........] - ETA: 0s - loss: 0.0000e+00 - accuracy: 0.9417
# 11/12 [==========================>...] - ETA: 0s - loss: 0.0000e+00 - accuracy: 0.9422
# 12/12 [==============================] - 3s 26ms/step - loss: 0.0000e+00 - accuracy: 0.9420
# loss: 0.0000
# accuracy: 0.9420

# %%
# Model Summary
model.summary()
# Out:
# Model: "random_forest_model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
# =================================================================
# Total params: 1 (1.00 Byte)
# Trainable params: 0 (0.00 Byte)
# Non-trainable params: 1 (1.00 Byte)
# _________________________________________________________________
# Type: "RANDOM_FOREST"
# Task: CLASSIFICATION
# Label: "__LABEL"
#
# Input Features (16):
# 	GrayLevelNonUniformity
# 	GrayLevelNonUniformityNormalized
# 	GrayLevelVariance
# 	HighGrayLevelZoneEmphasis
# 	LargeAreaEmphasis
# 	LargeAreaHighGrayLevelEmphasis
# 	LargeAreaLowGrayLevelEmphasis
# 	LowGrayLevelZoneEmphasis
# 	SizeZoneNonUniformity
# 	SizeZoneNonUniformityNormalized
# 	SmallAreaEmphasis
# 	SmallAreaHighGrayLevelEmphasis
# 	SmallAreaLowGrayLevelEmphasis
# 	ZoneEntropy
# 	ZonePercentage
# 	ZoneVariance
#
# Trained with weights
#
# Variable Importance: INV_MEAN_MIN_DEPTH:
#     1.        "HighGrayLevelZoneEmphasis"  0.203274 ################
#     2.           "GrayLevelNonUniformity"  0.163251 ##########
#     3.   "SmallAreaHighGrayLevelEmphasis"  0.138093 #######
#     4.   "LargeAreaHighGrayLevelEmphasis"  0.135733 ######
#     5.         "LowGrayLevelZoneEmphasis"  0.130349 ######
#     6.    "LargeAreaLowGrayLevelEmphasis"  0.121260 ####
#     7.    "SmallAreaLowGrayLevelEmphasis"  0.115022 ####
#     8.                      "ZoneEntropy"  0.108636 ###
#     9.  "SizeZoneNonUniformityNormalized"  0.098379 #
#    10.                "SmallAreaEmphasis"  0.096920 #
#    11. "GrayLevelNonUniformityNormalized"  0.090676
#    12.            "SizeZoneNonUniformity"  0.090457
#    13.                "GrayLevelVariance"  0.089219
#    14.                     "ZoneVariance"  0.088780
#    15.                   "ZonePercentage"  0.086053
#    16.                "LargeAreaEmphasis"  0.085526
#
# Variable Importance: NUM_AS_ROOT:
#     1.        "HighGrayLevelZoneEmphasis" 85.000000 ################
#     2.   "SmallAreaHighGrayLevelEmphasis" 83.000000 ###############
#     3.         "LowGrayLevelZoneEmphasis" 48.000000 ########
#     4.    "SmallAreaLowGrayLevelEmphasis" 30.000000 #####
#     5.    "LargeAreaLowGrayLevelEmphasis" 22.000000 ####
#     6.                      "ZoneEntropy" 18.000000 ###
#     7.           "GrayLevelNonUniformity"  6.000000
#     8.   "LargeAreaHighGrayLevelEmphasis"  5.000000
#     9.                "GrayLevelVariance"  2.000000
#    10. "GrayLevelNonUniformityNormalized"  1.000000
#
# Variable Importance: NUM_NODES:
#     1.           "GrayLevelNonUniformity" 26737.000000 ################
#     2.    "LargeAreaLowGrayLevelEmphasis" 26660.000000 ###############
#     3.   "LargeAreaHighGrayLevelEmphasis" 26078.000000 ###############
#     4.        "HighGrayLevelZoneEmphasis" 23834.000000 ###########
#     5.         "LowGrayLevelZoneEmphasis" 22957.000000 ##########
#     6.                      "ZoneEntropy" 22331.000000 #########
#     7.                "GrayLevelVariance" 21633.000000 ########
#     8.   "SmallAreaHighGrayLevelEmphasis" 21209.000000 #######
#     9.                     "ZoneVariance" 21132.000000 #######
#    10.    "SmallAreaLowGrayLevelEmphasis" 20866.000000 #######
#    11. "GrayLevelNonUniformityNormalized" 20840.000000 #######
#    12.                "LargeAreaEmphasis" 18876.000000 ####
#    13.            "SizeZoneNonUniformity" 17870.000000 ##
#    14.  "SizeZoneNonUniformityNormalized" 17767.000000 ##
#    15.                "SmallAreaEmphasis" 17684.000000 ##
#    16.                   "ZonePercentage" 15932.000000
#
# Variable Importance: SUM_SCORE:
#     1.        "HighGrayLevelZoneEmphasis" 2398519.423361 ################
#     2.   "SmallAreaHighGrayLevelEmphasis" 1556888.985342 #########
#     3.           "GrayLevelNonUniformity" 1513897.050694 #########
#     4.         "LowGrayLevelZoneEmphasis" 1216857.443615 ######
#     5.   "LargeAreaHighGrayLevelEmphasis" 1097081.597462 #####
#     6.    "LargeAreaLowGrayLevelEmphasis" 942027.072365 ####
#     7.    "SmallAreaLowGrayLevelEmphasis" 916315.497387 ####
#     8.                      "ZoneEntropy" 850936.673522 ####
#     9.  "SizeZoneNonUniformityNormalized" 520721.152489 #
#    10.                "SmallAreaEmphasis" 499958.568093 #
#    11. "GrayLevelNonUniformityNormalized" 455886.643854
#    12.                "GrayLevelVariance" 439890.613942
#    13.                     "ZoneVariance" 429079.894978
#    14.            "SizeZoneNonUniformity" 414833.241773
#    15.                "LargeAreaEmphasis" 343748.645076
#    16.                   "ZonePercentage" 329311.327459
#
#
#
# Winner takes all: true
# Out-of-bag evaluation: accuracy:0.851189 logloss:0.428839
# Number of trees: 300
# Total number of nodes: 685112
#
# Number of nodes by tree:
# Count: 300 Average: 2283.71 StdDev: 168.739
# Min: 1741 Max: 2629 Ignored: 0
# ----------------------------------------------
# [ 1741, 1785)  1   0.33%   0.33%
# [ 1785, 1829)  3   1.00%   1.33% #
# [ 1829, 1874)  1   0.33%   1.67%
# [ 1874, 1918)  0   0.00%   1.67%
# [ 1918, 1963)  4   1.33%   3.00% #
# [ 1963, 2007)  9   3.00%   6.00% ###
# [ 2007, 2052)  9   3.00%   9.00% ###
# [ 2052, 2096) 16   5.33%  14.33% #####
# [ 2096, 2141) 21   7.00%  21.33% ######
# [ 2141, 2185) 19   6.33%  27.67% #####
# [ 2185, 2229) 26   8.67%  36.33% #######
# [ 2229, 2274) 26   8.67%  45.00% #######
# [ 2274, 2318) 21   7.00%  52.00% ######
# [ 2318, 2363) 33  11.00%  63.00% #########
# [ 2363, 2407) 35  11.67%  74.67% ##########
# [ 2407, 2452) 27   9.00%  83.67% ########
# [ 2452, 2496) 20   6.67%  90.33% ######
# [ 2496, 2541) 15   5.00%  95.33% ####
# [ 2541, 2585) 10   3.33%  98.67% ###
# [ 2585, 2629]  4   1.33% 100.00% #
#
# Depth by leafs:
# Count: 342706 Average: 12.4305 StdDev: 2.31984
# Min: 3 Max: 15 Ignored: 0
# ----------------------------------------------
# [  3,  4)     7   0.00%   0.00%
# [  4,  5)   167   0.05%   0.05%
# [  5,  6)  1033   0.30%   0.35%
# [  6,  7)  2995   0.87%   1.23%
# [  7,  8)  6759   1.97%   3.20% #
# [  8,  9) 12364   3.61%   6.81% #
# [  9, 10) 19923   5.81%  12.62% ##
# [ 10, 11) 29002   8.46%  21.08% ###
# [ 11, 12) 37842  11.04%  32.12% ####
# [ 12, 13) 45044  13.14%  45.27% #####
# [ 13, 14) 49331  14.39%  59.66% ######
# [ 14, 15) 51061  14.90%  74.56% ######
# [ 15, 15] 87178  25.44% 100.00% ##########
#
# Number of training obs by leaf:
# Count: 342706 Average: 68.9034 StdDev: 314.296
# Min: 5 Max: 12685 Ignored: 0
# ----------------------------------------------
# [     5,   639) 336355  98.15%  98.15% ##########
# [   639,  1273)   3532   1.03%  99.18%
# [  1273,  1907)   1104   0.32%  99.50%
# [  1907,  2541)    579   0.17%  99.67%
# [  2541,  3175)    342   0.10%  99.77%
# [  3175,  3809)    215   0.06%  99.83%
# [  3809,  4443)    150   0.04%  99.87%
# [  4443,  5077)    127   0.04%  99.91%
# [  5077,  5711)     76   0.02%  99.93%
# [  5711,  6345)     69   0.02%  99.95%
# [  6345,  6979)     53   0.02%  99.97%
# [  6979,  7613)     49   0.01%  99.98%
# [  7613,  8247)     21   0.01%  99.99%
# [  8247,  8881)     16   0.00%  99.99%
# [  8881,  9515)      7   0.00% 100.00%
# [  9515, 10149)      4   0.00% 100.00%
# [ 10149, 10783)      4   0.00% 100.00%
# [ 10783, 11417)      1   0.00% 100.00%
# [ 11417, 12051)      1   0.00% 100.00%
# [ 12051, 12685]      1   0.00% 100.00%
#
# Attribute in nodes:
# 	26737 : GrayLevelNonUniformity [NUMERICAL]
# 	26660 : LargeAreaLowGrayLevelEmphasis [NUMERICAL]
# 	26078 : LargeAreaHighGrayLevelEmphasis [NUMERICAL]
# 	23834 : HighGrayLevelZoneEmphasis [NUMERICAL]
# 	22957 : LowGrayLevelZoneEmphasis [NUMERICAL]
# 	22331 : ZoneEntropy [NUMERICAL]
# 	21633 : GrayLevelVariance [NUMERICAL]
# 	21209 : SmallAreaHighGrayLevelEmphasis [NUMERICAL]
# 	21132 : ZoneVariance [NUMERICAL]
# 	20866 : SmallAreaLowGrayLevelEmphasis [NUMERICAL]
# 	20840 : GrayLevelNonUniformityNormalized [NUMERICAL]
# 	18876 : LargeAreaEmphasis [NUMERICAL]
# 	17870 : SizeZoneNonUniformity [NUMERICAL]
# 	17767 : SizeZoneNonUniformityNormalized [NUMERICAL]
# 	17684 : SmallAreaEmphasis [NUMERICAL]
# 	15932 : ZonePercentage [NUMERICAL]
#
# Attribute in nodes with depth <= 0:
# 	85 : HighGrayLevelZoneEmphasis [NUMERICAL]
# 	83 : SmallAreaHighGrayLevelEmphasis [NUMERICAL]
# 	48 : LowGrayLevelZoneEmphasis [NUMERICAL]
# 	30 : SmallAreaLowGrayLevelEmphasis [NUMERICAL]
# 	22 : LargeAreaLowGrayLevelEmphasis [NUMERICAL]
# 	18 : ZoneEntropy [NUMERICAL]
# 	6 : GrayLevelNonUniformity [NUMERICAL]
# 	5 : LargeAreaHighGrayLevelEmphasis [NUMERICAL]
# 	2 : GrayLevelVariance [NUMERICAL]
# 	1 : GrayLevelNonUniformityNormalized [NUMERICAL]
#
# Attribute in nodes with depth <= 1:
# 	221 : HighGrayLevelZoneEmphasis [NUMERICAL]
# 	150 : SmallAreaHighGrayLevelEmphasis [NUMERICAL]
# 	107 : LowGrayLevelZoneEmphasis [NUMERICAL]
# 	94 : GrayLevelNonUniformity [NUMERICAL]
# 	92 : LargeAreaHighGrayLevelEmphasis [NUMERICAL]
# 	66 : SmallAreaLowGrayLevelEmphasis [NUMERICAL]
# 	42 : ZoneEntropy [NUMERICAL]
# 	31 : SmallAreaEmphasis [NUMERICAL]
# 	31 : SizeZoneNonUniformityNormalized [NUMERICAL]
# 	27 : LargeAreaLowGrayLevelEmphasis [NUMERICAL]
# 	10 : ZonePercentage [NUMERICAL]
# 	10 : SizeZoneNonUniformity [NUMERICAL]
# 	7 : LargeAreaEmphasis [NUMERICAL]
# 	6 : GrayLevelNonUniformityNormalized [NUMERICAL]
# 	5 : GrayLevelVariance [NUMERICAL]
# 	1 : ZoneVariance [NUMERICAL]
#
# Attribute in nodes with depth <= 2:
# 	488 : HighGrayLevelZoneEmphasis [NUMERICAL]
# 	249 : LowGrayLevelZoneEmphasis [NUMERICAL]
# 	248 : SmallAreaHighGrayLevelEmphasis [NUMERICAL]
# 	236 : GrayLevelNonUniformity [NUMERICAL]
# 	204 : SmallAreaLowGrayLevelEmphasis [NUMERICAL]
# 	188 : LargeAreaHighGrayLevelEmphasis [NUMERICAL]
# 	145 : ZoneEntropy [NUMERICAL]
# 	116 : LargeAreaLowGrayLevelEmphasis [NUMERICAL]
# 	51 : SizeZoneNonUniformityNormalized [NUMERICAL]
# 	45 : SmallAreaEmphasis [NUMERICAL]
# 	41 : GrayLevelNonUniformityNormalized [NUMERICAL]
# 	31 : GrayLevelVariance [NUMERICAL]
# 	21 : SizeZoneNonUniformity [NUMERICAL]
# 	15 : ZonePercentage [NUMERICAL]
# 	14 : LargeAreaEmphasis [NUMERICAL]
# 	8 : ZoneVariance [NUMERICAL]
#
# Attribute in nodes with depth <= 3:
# 	811 : HighGrayLevelZoneEmphasis [NUMERICAL]
# 	583 : GrayLevelNonUniformity [NUMERICAL]
# 	471 : LargeAreaHighGrayLevelEmphasis [NUMERICAL]
# 	446 : LowGrayLevelZoneEmphasis [NUMERICAL]
# 	381 : SmallAreaLowGrayLevelEmphasis [NUMERICAL]
# 	367 : SmallAreaHighGrayLevelEmphasis [NUMERICAL]
# 	333 : ZoneEntropy [NUMERICAL]
# 	284 : LargeAreaLowGrayLevelEmphasis [NUMERICAL]
# 	138 : SizeZoneNonUniformityNormalized [NUMERICAL]
# 	130 : GrayLevelNonUniformityNormalized [NUMERICAL]
# 	115 : SmallAreaEmphasis [NUMERICAL]
# 	111 : GrayLevelVariance [NUMERICAL]
# 	102 : SizeZoneNonUniformity [NUMERICAL]
# 	82 : LargeAreaEmphasis [NUMERICAL]
# 	72 : ZoneVariance [NUMERICAL]
# 	67 : ZonePercentage [NUMERICAL]
#
# Attribute in nodes with depth <= 5:
# 	2174 : GrayLevelNonUniformity [NUMERICAL]
# 	2121 : HighGrayLevelZoneEmphasis [NUMERICAL]
# 	1665 : LargeAreaHighGrayLevelEmphasis [NUMERICAL]
# 	1436 : LowGrayLevelZoneEmphasis [NUMERICAL]
# 	1354 : LargeAreaLowGrayLevelEmphasis [NUMERICAL]
# 	1332 : ZoneEntropy [NUMERICAL]
# 	1118 : SmallAreaLowGrayLevelEmphasis [NUMERICAL]
# 	920 : SmallAreaHighGrayLevelEmphasis [NUMERICAL]
# 	815 : GrayLevelNonUniformityNormalized [NUMERICAL]
# 	799 : GrayLevelVariance [NUMERICAL]
# 	660 : SizeZoneNonUniformityNormalized [NUMERICAL]
# 	657 : SmallAreaEmphasis [NUMERICAL]
# 	631 : ZoneVariance [NUMERICAL]
# 	616 : SizeZoneNonUniformity [NUMERICAL]
# 	562 : LargeAreaEmphasis [NUMERICAL]
# 	457 : ZonePercentage [NUMERICAL]
#
# Condition type in nodes:
# 	342406 : HigherCondition
# Condition type in nodes with depth <= 0:
# 	300 : HigherCondition
# Condition type in nodes with depth <= 1:
# 	900 : HigherCondition
# Condition type in nodes with depth <= 2:
# 	2100 : HigherCondition
# Condition type in nodes with depth <= 3:
# 	4493 : HigherCondition
# Condition type in nodes with depth <= 5:
# 	17317 : HigherCondition
# Node format: NOT_SET
#
# Training OOB:
# 	trees: 1, Out-of-bag evaluation: accuracy:0.811575 logloss:6.79153
# 	trees: 11, Out-of-bag evaluation: accuracy:0.823277 logloss:2.60147
# 	trees: 21, Out-of-bag evaluation: accuracy:0.83702 logloss:1.4852
# 	trees: 31, Out-of-bag evaluation: accuracy:0.839843 logloss:1.12835
# 	trees: 42, Out-of-bag evaluation: accuracy:0.843351 logloss:0.976712
# 	trees: 52, Out-of-bag evaluation: accuracy:0.845406 logloss:0.845977
# 	trees: 62, Out-of-bag evaluation: accuracy:0.845854 logloss:0.787617
# 	trees: 72, Out-of-bag evaluation: accuracy:0.84691 logloss:0.72644
# 	trees: 82, Out-of-bag evaluation: accuracy:0.846625 logloss:0.679911
# 	trees: 92, Out-of-bag evaluation: accuracy:0.8483 logloss:0.647017
# 	trees: 102, Out-of-bag evaluation: accuracy:0.847634 logloss:0.610932
# 	trees: 112, Out-of-bag evaluation: accuracy:0.846831 logloss:0.592239
# 	trees: 122, Out-of-bag evaluation: accuracy:0.847745 logloss:0.573963
# 	trees: 132, Out-of-bag evaluation: accuracy:0.849318 logloss:0.558803
# 	trees: 142, Out-of-bag evaluation: accuracy:0.849999 logloss:0.54952
# 	trees: 152, Out-of-bag evaluation: accuracy:0.850516 logloss:0.5258
# 	trees: 162, Out-of-bag evaluation: accuracy:0.850175 logloss:0.522241
# 	trees: 172, Out-of-bag evaluation: accuracy:0.850358 logloss:0.515768
# 	trees: 182, Out-of-bag evaluation: accuracy:0.850406 logloss:0.50711
# 	trees: 192, Out-of-bag evaluation: accuracy:0.850236 logloss:0.499339
# 	trees: 202, Out-of-bag evaluation: accuracy:0.850536 logloss:0.490271
# 	trees: 212, Out-of-bag evaluation: accuracy:0.851121 logloss:0.486998
# 	trees: 222, Out-of-bag evaluation: accuracy:0.850509 logloss:0.477731
# 	trees: 232, Out-of-bag evaluation: accuracy:0.850666 logloss:0.47219
# 	trees: 242, Out-of-bag evaluation: accuracy:0.849869 logloss:0.468634
# 	trees: 252, Out-of-bag evaluation: accuracy:0.850842 logloss:0.454711
# 	trees: 262, Out-of-bag evaluation: accuracy:0.850263 logloss:0.451684
# 	trees: 272, Out-of-bag evaluation: accuracy:0.851162 logloss:0.440116
# 	trees: 282, Out-of-bag evaluation: accuracy:0.8511 logloss:0.434367
# 	trees: 292, Out-of-bag evaluation: accuracy:0.851222 logloss:0.431594
# 	trees: 300, Out-of-bag evaluation: accuracy:0.851189 logloss:0.428839

# %%
# Model features
model.make_inspector().features()
# Out:
# ["GrayLevelNonUniformity" (1; #0),
#  "GrayLevelNonUniformityNormalized" (1; #1),
#  "GrayLevelVariance" (1; #2),
#  "HighGrayLevelZoneEmphasis" (1; #3),
#  "LargeAreaEmphasis" (1; #4),
#  "LargeAreaHighGrayLevelEmphasis" (1; #5),
#  "LargeAreaLowGrayLevelEmphasis" (1; #6),
#  "LowGrayLevelZoneEmphasis" (1; #7),
#  "SizeZoneNonUniformity" (1; #8),
#  "SizeZoneNonUniformityNormalized" (1; #9),
#  "SmallAreaEmphasis" (1; #10),
#  "SmallAreaHighGrayLevelEmphasis" (1; #11),
#  "SmallAreaLowGrayLevelEmphasis" (1; #12),
#  "ZoneEntropy" (1; #13),
#  "ZonePercentage" (1; #14),
#  "ZoneVariance" (1; #15)]

# %%
# Feature importance
model.make_inspector().variable_importances()
# Out:
# {'INV_MEAN_MIN_DEPTH': [("HighGrayLevelZoneEmphasis" (1; #3),
#    0.20327405960191328),
#   ("GrayLevelNonUniformity" (1; #0), 0.16325111502161987),
#   ("SmallAreaHighGrayLevelEmphasis" (1; #11), 0.1380925454390524),
#   ("LargeAreaHighGrayLevelEmphasis" (1; #5), 0.1357328670992708),
#   ("LowGrayLevelZoneEmphasis" (1; #7), 0.13034855392320413),
#   ("LargeAreaLowGrayLevelEmphasis" (1; #6), 0.12126001927889053),
#   ("SmallAreaLowGrayLevelEmphasis" (1; #12), 0.11502248069260901),
#   ("ZoneEntropy" (1; #13), 0.10863576044761873),
#   ("SizeZoneNonUniformityNormalized" (1; #9), 0.09837865743746987),
#   ("SmallAreaEmphasis" (1; #10), 0.09692032121873986),
#   ("GrayLevelNonUniformityNormalized" (1; #1), 0.09067583967397846),
#   ("SizeZoneNonUniformity" (1; #8), 0.09045746618061379),
#   ("GrayLevelVariance" (1; #2), 0.08921859302107374),
#   ("ZoneVariance" (1; #15), 0.08877950199870169),
#   ("ZonePercentage" (1; #14), 0.08605309125802421),
#   ("LargeAreaEmphasis" (1; #4), 0.08552622043624185)],
#  'NUM_AS_ROOT': [("HighGrayLevelZoneEmphasis" (1; #3), 85.0),
#   ("SmallAreaHighGrayLevelEmphasis" (1; #11), 83.0),
#   ("LowGrayLevelZoneEmphasis" (1; #7), 48.0),
#   ("SmallAreaLowGrayLevelEmphasis" (1; #12), 30.0),
#   ("LargeAreaLowGrayLevelEmphasis" (1; #6), 22.0),
#   ("ZoneEntropy" (1; #13), 18.0),
#   ("GrayLevelNonUniformity" (1; #0), 6.0),
#   ("LargeAreaHighGrayLevelEmphasis" (1; #5), 5.0),
#   ("GrayLevelVariance" (1; #2), 2.0),
#   ("GrayLevelNonUniformityNormalized" (1; #1), 1.0)],
#  'SUM_SCORE': [("HighGrayLevelZoneEmphasis" (1; #3), 2398519.4233605443),
#   ("SmallAreaHighGrayLevelEmphasis" (1; #11), 1556888.9853417727),
#   ("GrayLevelNonUniformity" (1; #0), 1513897.050694168),
#   ("LowGrayLevelZoneEmphasis" (1; #7), 1216857.4436149294),
#   ("LargeAreaHighGrayLevelEmphasis" (1; #5), 1097081.5974624373),
#   ("LargeAreaLowGrayLevelEmphasis" (1; #6), 942027.0723652287),
#   ("SmallAreaLowGrayLevelEmphasis" (1; #12), 916315.4973873143),
#   ("ZoneEntropy" (1; #13), 850936.6735216817),
#   ("SizeZoneNonUniformityNormalized" (1; #9), 520721.1524893456),
#   ("SmallAreaEmphasis" (1; #10), 499958.56809346646),
#   ("GrayLevelNonUniformityNormalized" (1; #1), 455886.6438537131),
#   ("GrayLevelVariance" (1; #2), 439890.6139419121),
#   ("ZoneVariance" (1; #15), 429079.89497811423),
#   ("SizeZoneNonUniformity" (1; #8), 414833.24177322147),
#   ("LargeAreaEmphasis" (1; #4), 343748.64507594606),
#   ("ZonePercentage" (1; #14), 329311.32745931926)],
#  'NUM_NODES': [("GrayLevelNonUniformity" (1; #0), 26737.0),
#   ("LargeAreaLowGrayLevelEmphasis" (1; #6), 26660.0),
#   ("LargeAreaHighGrayLevelEmphasis" (1; #5), 26078.0),
#   ("HighGrayLevelZoneEmphasis" (1; #3), 23834.0),
#   ("LowGrayLevelZoneEmphasis" (1; #7), 22957.0),
#   ("ZoneEntropy" (1; #13), 22331.0),
#   ("GrayLevelVariance" (1; #2), 21633.0),
#   ("SmallAreaHighGrayLevelEmphasis" (1; #11), 21209.0),
#   ("ZoneVariance" (1; #15), 21132.0),
#   ("SmallAreaLowGrayLevelEmphasis" (1; #12), 20866.0),
#   ("GrayLevelNonUniformityNormalized" (1; #1), 20840.0),
#   ("LargeAreaEmphasis" (1; #4), 18876.0),
#   ("SizeZoneNonUniformity" (1; #8), 17870.0),
#   ("SizeZoneNonUniformityNormalized" (1; #9), 17767.0),
#   ("SmallAreaEmphasis" (1; #10), 17684.0),
#   ("ZonePercentage" (1; #14), 15932.0)]}

# %%
# Model self evaluation
model.make_inspector().evaluation()
# Out:
# Evaluation(num_examples=78712, accuracy=0.8511887525389963, loss=0.428838587455799, rmse=None, ndcg=None, aucs=None, auuc=None, qini=None)

# %%
logs = model.make_inspector().training_logs()

plt.figure(figsize=(12, 4))
plt.subplot(1, 2, 1)
plt.plot([log.num_trees for log in logs], [log.evaluation.accuracy for log in logs])
plt.xlabel("Number of trees")
plt.ylabel("Accuracy (out-of-bag)")
plt.subplot(1, 2, 2)
plt.plot([log.num_trees for log in logs], [log.evaluation.loss for log in logs])
plt.xlabel("Number of trees")
plt.ylabel("Logloss (out-of-bag)")
plt.show()

# %% [markdown]
# Calculate the score of our hold-out validation dataset

# %%
predictions = model.predict(val_ds)
y_true      = validation_data["label"]

from sklearn.metrics import roc_auc_score
ROC_AUC = roc_auc_score(y_true, predictions)
print("The ROC AUC score is %.5f" % ROC_AUC )
# Out:
#  1/12 [=>............................] - ETA: 0s
#  3/12 [======>.......................] - ETA: 0s
#  5/12 [===========>..................] - ETA: 0s
#  7/12 [================>.............] - ETA: 0s
#  9/12 [=====================>........] - ETA: 0s
# 11/12 [==========================>...] - ETA: 0s
# 12/12 [==============================] - 0s 26ms/step
# The ROC AUC score is 0.95581

# %%
# Compute binary classification metrics with sklearn
import numpy as np
from sklearn.metrics import (
    accuracy_score,
    precision_score,
    recall_score,
    f1_score,
    roc_auc_score,
    average_precision_score,
    confusion_matrix,
    classification_report,
    matthews_corrcoef,
    log_loss,
    brier_score_loss,
)

# Get predictions (probabilities or class labels)
preds = model.predict(test_ds)
# If model outputs probabilities, convert to labels by threshold 0.5
if preds.ndim == 2:
    # For TFDF classification, preds may be class probabilities with shape (N, 2)
    if preds.shape[1] == 2:
        pos_probs = preds[:, 1]
    else:
        # If single-probability column (positive class)
        pos_probs = preds[:, -1]
    y_pred = (pos_probs >= 0.5).astype(int)
else:
    # Already class labels
    y_pred = preds.astype(int)
    pos_probs = None

# Ground truth labels (must be 0/1 integers)
y_true = test_data["label"].astype(int).to_numpy()

# Core metrics
metrics = {}
metrics["accuracy"] = accuracy_score(y_true, y_pred)
metrics["precision"] = precision_score(y_true, y_pred, zero_division=0)
metrics["recall"] = recall_score(y_true, y_pred, zero_division=0)
metrics["f1"] = f1_score(y_true, y_pred, zero_division=0)
metrics["mcc"] = matthews_corrcoef(y_true, y_pred)

# Probabilistic metrics (only if we have probabilities)
if pos_probs is not None:
    metrics["roc_auc"] = roc_auc_score(y_true, pos_probs)
    metrics["pr_auc"] = average_precision_score(y_true, pos_probs)
    metrics["log_loss"] = log_loss(y_true, pos_probs, labels=[0,1])
    metrics["brier_score"] = brier_score_loss(y_true, pos_probs)

# Confusion matrix and detailed report
cm = confusion_matrix(y_true, y_pred, labels=[0,1])
report = classification_report(y_true, y_pred, digits=4)

print("Sklearn binary metrics:")
for k, v in metrics.items():
    print(f"{k}: {v:.4f}")
print("\nConfusion matrix:\n", cm)
print("\nClassification report:\n", report)
# Out:
#  1/23 [>.............................] - ETA: 2s
#  3/23 [==>...........................] - ETA: 0s
#  5/23 [=====>........................] - ETA: 0s
#  7/23 [========>.....................] - ETA: 0s
#  9/23 [==========>...................] - ETA: 0s
# 11/23 [=============>................] - ETA: 0s
# 13/23 [===============>..............] - ETA: 0s
# 15/23 [==================>...........] - ETA: 0s
# 17/23 [=====================>........] - ETA: 0s
# 19/23 [=======================>......] - ETA: 0s
# 21/23 [==========================>...] - ETA: 0s
# 23/23 [==============================] - 1s 26ms/step
# Sklearn binary metrics:
# accuracy: 0.9407
# precision: 0.5748
# recall: 0.7494
# f1: 0.6506
# mcc: 0.6253
# roc_auc: 0.9503
# pr_auc: 0.7559
# log_loss: 0.1569
# brier_score: 0.0450
#
# Confusion matrix:
#  [[19916   918]
#  [  415  1241]]
#
# Classification report:
#                precision    recall  f1-score   support
#
#            0     0.9796    0.9559    0.9676     20834
#            1     0.5748    0.7494    0.6506      1656
#
#     accuracy                         0.9407     22490
#    macro avg     0.7772    0.8527    0.8091     22490
# weighted avg     0.9498    0.9407    0.9443     22490
