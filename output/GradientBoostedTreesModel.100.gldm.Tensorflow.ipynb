# %%
# Import packages and modules
import numpy  as np
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow_decision_forests as tfdf

from sklearn.model_selection import train_test_split
# Out:
# 2026-07-04 08:33:12.422773: I tensorflow/core/util/port.cc:113] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2026-07-04 08:33:12.463998: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2026-07-04 08:33:18.345780: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
# Check the version of TensorFlow Decision Forests
print("Found TensorFlow Decision Forests v" + tfdf.__version__)
# Out:
# Found TensorFlow Decision Forests v1.9.1

# %%
datasetPath = 'dataset/firstorder/kernel5-radius5/dataset.csv'

# %%
# Parameters
datasetPath = "dataset/gldm/kernel5-radius5/100.dataset.csv"

# %%
# train/validation/test = 70/10/20
dataset = pd.read_csv(datasetPath)

train_data, temp_data = train_test_split(dataset, test_size=0.3, random_state=42)
validation_data, test_data = train_test_split(temp_data, test_size=2/3, random_state=42)

# %%
from sklearn.utils.class_weight import compute_class_weight

# tinh class weight tren tap train
classes = np.array([0, 1])
weights = compute_class_weight(class_weight="balanced", classes=classes, y=train_data["label"])
class_weight = {0: weights[0], 1: weights[1]}

# gan sample_weight cho tung dong
train_data["sample_weight"] = train_data["label"].map(class_weight)
validation_data["sample_weight"] = validation_data["label"].map(class_weight)
test_data["sample_weight"] = test_data["label"].map(class_weight)

# Convert the dataset into a TensorFlow dataset.
train_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    train_data, label="label", weight="sample_weight"
)         
val_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    validation_data, label="label", weight="sample_weight"
)
test_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    test_data, label="label", weight="sample_weight"
)
# Out:
# 2026-07-04 08:33:30.410906: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:984] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2026-07-04 08:33:30.412138: W tensorflow/core/common_runtime/gpu/gpu_device.cc:2251] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...

# %%
import keras

# %%
# %%time

# Train a Gradient Boosted Trees model.
model = tfdf.keras.GradientBoostedTreesModel()

# Add evaluation metrics
model.compile(
    metrics=["accuracy"]
)
model.fit(x=train_ds)

# # Train a Gradient Boosted Trees model.
# model = tfdf.keras.GradientBoostedTreesModel(num_trees=1500)
# model.fit(train_ds)
# Out:
# Use /tmp/tmpfqsc1pti as temporary training directory
# Reading training dataset...
# [WARNING 26-07-04 08:33:30.5438 UTC gradient_boosted_trees.cc:1840] "goss_alpha" set but "sampling_method" not equal to "GOSS".
# [WARNING 26-07-04 08:33:30.5439 UTC gradient_boosted_trees.cc:1851] "goss_beta" set but "sampling_method" not equal to "GOSS".
# [WARNING 26-07-04 08:33:30.5439 UTC gradient_boosted_trees.cc:1865] "selective_gradient_boosting_ratio" set but "sampling_method" not equal to "SELGB".
# Training dataset read in 0:00:02.746503. Found 78790 examples.
# Training model...
# Model trained in 0:00:10.202260
# Compiling model...
# [INFO 26-07-04 08:33:43.5110 UTC kernel.cc:1233] Loading model from path /tmp/tmpfqsc1pti/model/ with prefix 5c5798d26fec40e1
# [INFO 26-07-04 08:33:43.5188 UTC quick_scorer_extended.cc:911] The binary was compiled without AVX2 support, but your CPU supports it. Enable it for faster model inference.
# [INFO 26-07-04 08:33:43.5194 UTC abstract_model.cc:1362] Engine "GradientBoostedTreesQuickScorerExtended" built
# [INFO 26-07-04 08:33:43.5194 UTC kernel.cc:1061] Use fast generic engine
# Model compiled.
# CPU times: user 1min 13s, sys: 1.38 s, total: 1min 15s
# Wall time: 17.5 s

# %%
# Evaluate the model
evaluate = model.evaluate(val_ds, return_dict=True)
print()

for name, value in evaluate.items():
    print(f"{name}: {value:.4f}")
# Out:
# WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
#  1/12 [=>............................] - ETA: 32s - loss: 0.0000e+00 - accuracy: 0.9190
# 12/12 [==============================] - 3s 4ms/step - loss: 0.0000e+00 - accuracy: 0.9254
# loss: 0.0000
# accuracy: 0.9254

# %%
# Model Summary
model.summary()
# Out:
# Model: "gradient_boosted_trees_model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
# =================================================================
# Total params: 1 (1.00 Byte)
# Trainable params: 0 (0.00 Byte)
# Non-trainable params: 1 (1.00 Byte)
# _________________________________________________________________
# Type: "GRADIENT_BOOSTED_TREES"
# Task: CLASSIFICATION
# Label: "__LABEL"
#
# Input Features (14):
# 	DependenceEntropy
# 	DependenceNonUniformity
# 	DependenceNonUniformityNormalized
# 	DependenceVariance
# 	GrayLevelNonUniformity
# 	GrayLevelVariance
# 	HighGrayLevelEmphasis
# 	LargeDependenceEmphasis
# 	LargeDependenceHighGrayLevelEmphasis
# 	LargeDependenceLowGrayLevelEmphasis
# 	LowGrayLevelEmphasis
# 	SmallDependenceEmphasis
# 	SmallDependenceHighGrayLevelEmphasis
# 	SmallDependenceLowGrayLevelEmphasis
#
# Trained with weights
#
# Variable Importance: INV_MEAN_MIN_DEPTH:
#     1. "LargeDependenceHighGrayLevelEmphasis"  0.309987 ################
#     2.                    "DependenceEntropy"  0.230857 ######
#     3.               "GrayLevelNonUniformity"  0.214536 ####
#     4.                "HighGrayLevelEmphasis"  0.212589 ####
#     5.  "SmallDependenceLowGrayLevelEmphasis"  0.207201 ###
#     6.              "SmallDependenceEmphasis"  0.206837 ###
#     7.                    "GrayLevelVariance"  0.196865 ##
#     8. "SmallDependenceHighGrayLevelEmphasis"  0.195183 ##
#     9.  "LargeDependenceLowGrayLevelEmphasis"  0.187700 #
#    10.                   "DependenceVariance"  0.187093 #
#    11.                 "LowGrayLevelEmphasis"  0.180232
#    12.              "LargeDependenceEmphasis"  0.178958
#    13.    "DependenceNonUniformityNormalized"  0.174020
#    14.              "DependenceNonUniformity"  0.174017
#
# Variable Importance: NUM_AS_ROOT:
#     1. "LargeDependenceHighGrayLevelEmphasis" 71.000000 ################
#     2.               "GrayLevelNonUniformity" 19.000000 ####
#     3.                    "DependenceEntropy" 17.000000 ###
#     4.                "HighGrayLevelEmphasis" 17.000000 ###
#     5.  "SmallDependenceLowGrayLevelEmphasis" 10.000000 ##
#     6.                    "GrayLevelVariance"  7.000000 #
#     7.  "LargeDependenceLowGrayLevelEmphasis"  4.000000
#     8.                   "DependenceVariance"  3.000000
#     9.              "SmallDependenceEmphasis"  1.000000
#    10. "SmallDependenceHighGrayLevelEmphasis"  1.000000
#
# Variable Importance: NUM_NODES:
#     1. "LargeDependenceHighGrayLevelEmphasis" 510.000000 ################
#     2.                    "DependenceEntropy" 469.000000 ##############
#     3.                "HighGrayLevelEmphasis" 391.000000 ###########
#     4.              "SmallDependenceEmphasis" 373.000000 ###########
#     5.                    "GrayLevelVariance" 365.000000 ##########
#     6.  "SmallDependenceLowGrayLevelEmphasis" 334.000000 #########
#     7. "SmallDependenceHighGrayLevelEmphasis" 324.000000 #########
#     8.               "GrayLevelNonUniformity" 303.000000 ########
#     9.  "LargeDependenceLowGrayLevelEmphasis" 222.000000 #####
#    10.                   "DependenceVariance" 217.000000 #####
#    11.                 "LowGrayLevelEmphasis" 179.000000 ####
#    12.              "LargeDependenceEmphasis" 162.000000 ###
#    13.    "DependenceNonUniformityNormalized" 76.000000
#    14.              "DependenceNonUniformity" 64.000000
#
# Variable Importance: SUM_SCORE:
#     1.                "HighGrayLevelEmphasis" 21975.662174 ################
#     2. "LargeDependenceHighGrayLevelEmphasis" 14161.451696 ##########
#     3.                    "DependenceEntropy" 11292.885014 ########
#     4.              "SmallDependenceEmphasis" 10343.279032 #######
#     5.  "SmallDependenceLowGrayLevelEmphasis" 5393.450647 ###
#     6.               "GrayLevelNonUniformity" 2418.469769 #
#     7.                 "LowGrayLevelEmphasis" 2211.857347 #
#     8. "SmallDependenceHighGrayLevelEmphasis" 2085.154349 #
#     9.                    "GrayLevelVariance" 1570.666865 #
#    10.                   "DependenceVariance" 1497.659919
#    11.  "LargeDependenceLowGrayLevelEmphasis" 1317.527321
#    12.              "LargeDependenceEmphasis" 556.441047
#    13.    "DependenceNonUniformityNormalized" 222.752247
#    14.              "DependenceNonUniformity" 169.321048
#
#
#
# Loss: BINOMIAL_LOG_LIKELIHOOD
# Validation loss value: 0.481765
# Number of trees per iteration: 1
# Node format: NOT_SET
# Number of trees: 150
# Total number of nodes: 8128
#
# Number of nodes by tree:
# Count: 150 Average: 54.1867 StdDev: 7.79092
# Min: 33 Max: 63 Ignored: 0
# ----------------------------------------------
# [ 33, 34)  1   0.67%   0.67%
# [ 34, 36)  3   2.00%   2.67% #
# [ 36, 37)  0   0.00%   2.67%
# [ 37, 39)  0   0.00%   2.67%
# [ 39, 40)  3   2.00%   4.67% #
# [ 40, 42)  4   2.67%   7.33% #
# [ 42, 43)  0   0.00%   7.33%
# [ 43, 45)  7   4.67%  12.00% ###
# [ 45, 46) 10   6.67%  18.67% ####
# [ 46, 48) 11   7.33%  26.00% ####
# [ 48, 50)  8   5.33%  31.33% ###
# [ 50, 51)  0   0.00%  31.33%
# [ 51, 53)  8   5.33%  36.67% ###
# [ 53, 54)  9   6.00%  42.67% ###
# [ 54, 56)  8   5.33%  48.00% ###
# [ 56, 57)  0   0.00%  48.00%
# [ 57, 59) 15  10.00%  58.00% ######
# [ 59, 60) 14   9.33%  67.33% #####
# [ 60, 62) 22  14.67%  82.00% ########
# [ 62, 63] 27  18.00% 100.00% ##########
#
# Depth by leafs:
# Count: 4139 Average: 4.892 StdDev: 0.427019
# Min: 2 Max: 5 Ignored: 0
# ----------------------------------------------
# [ 2, 3)   36   0.87%   0.87%
# [ 3, 4)   70   1.69%   2.56%
# [ 4, 5)  199   4.81%   7.37% #
# [ 5, 5] 3834  92.63% 100.00% ##########
#
# Number of training obs by leaf:
# Count: 4139 Average: 2569.79 StdDev: 8065.52
# Min: 5 Max: 65673 Ignored: 0
# ----------------------------------------------
# [     5,  3288) 3601  87.00%  87.00% ##########
# [  3288,  6571)  183   4.42%  91.42% #
# [  6571,  9855)   80   1.93%  93.36%
# [  9855, 13138)   59   1.43%  94.78%
# [ 13138, 16422)   36   0.87%  95.65%
# [ 16422, 19705)   25   0.60%  96.26%
# [ 19705, 22989)   25   0.60%  96.86%
# [ 22989, 26272)   22   0.53%  97.39%
# [ 26272, 29556)   15   0.36%  97.75%
# [ 29556, 32839)    9   0.22%  97.97%
# [ 32839, 36122)   10   0.24%  98.21%
# [ 36122, 39406)    6   0.14%  98.36%
# [ 39406, 42689)    8   0.19%  98.55%
# [ 42689, 45973)   10   0.24%  98.79%
# [ 45973, 49256)    4   0.10%  98.89%
# [ 49256, 52540)    9   0.22%  99.11%
# [ 52540, 55823)    8   0.19%  99.30%
# [ 55823, 59107)   11   0.27%  99.57%
# [ 59107, 62390)    9   0.22%  99.78%
# [ 62390, 65673]    9   0.22% 100.00%
#
# Attribute in nodes:
# 	510 : LargeDependenceHighGrayLevelEmphasis [NUMERICAL]
# 	469 : DependenceEntropy [NUMERICAL]
# 	391 : HighGrayLevelEmphasis [NUMERICAL]
# 	373 : SmallDependenceEmphasis [NUMERICAL]
# 	365 : GrayLevelVariance [NUMERICAL]
# 	334 : SmallDependenceLowGrayLevelEmphasis [NUMERICAL]
# 	324 : SmallDependenceHighGrayLevelEmphasis [NUMERICAL]
# 	303 : GrayLevelNonUniformity [NUMERICAL]
# 	222 : LargeDependenceLowGrayLevelEmphasis [NUMERICAL]
# 	217 : DependenceVariance [NUMERICAL]
# 	179 : LowGrayLevelEmphasis [NUMERICAL]
# 	162 : LargeDependenceEmphasis [NUMERICAL]
# 	76 : DependenceNonUniformityNormalized [NUMERICAL]
# 	64 : DependenceNonUniformity [NUMERICAL]
#
# Attribute in nodes with depth <= 0:
# 	71 : LargeDependenceHighGrayLevelEmphasis [NUMERICAL]
# 	19 : GrayLevelNonUniformity [NUMERICAL]
# 	17 : HighGrayLevelEmphasis [NUMERICAL]
# 	17 : DependenceEntropy [NUMERICAL]
# 	10 : SmallDependenceLowGrayLevelEmphasis [NUMERICAL]
# 	7 : GrayLevelVariance [NUMERICAL]
# 	4 : LargeDependenceLowGrayLevelEmphasis [NUMERICAL]
# 	3 : DependenceVariance [NUMERICAL]
# 	1 : SmallDependenceHighGrayLevelEmphasis [NUMERICAL]
# 	1 : SmallDependenceEmphasis [NUMERICAL]
#
# Attribute in nodes with depth <= 1:
# 	111 : LargeDependenceHighGrayLevelEmphasis [NUMERICAL]
# 	59 : DependenceEntropy [NUMERICAL]
# 	55 : GrayLevelNonUniformity [NUMERICAL]
# 	48 : HighGrayLevelEmphasis [NUMERICAL]
# 	44 : SmallDependenceEmphasis [NUMERICAL]
# 	42 : SmallDependenceLowGrayLevelEmphasis [NUMERICAL]
# 	21 : SmallDependenceHighGrayLevelEmphasis [NUMERICAL]
# 	17 : GrayLevelVariance [NUMERICAL]
# 	16 : LargeDependenceLowGrayLevelEmphasis [NUMERICAL]
# 	16 : DependenceVariance [NUMERICAL]
# 	9 : LargeDependenceEmphasis [NUMERICAL]
# 	7 : LowGrayLevelEmphasis [NUMERICAL]
# 	3 : DependenceNonUniformity [NUMERICAL]
# 	2 : DependenceNonUniformityNormalized [NUMERICAL]
#
# Attribute in nodes with depth <= 2:
# 	154 : LargeDependenceHighGrayLevelEmphasis [NUMERICAL]
# 	141 : DependenceEntropy [NUMERICAL]
# 	102 : SmallDependenceEmphasis [NUMERICAL]
# 	101 : HighGrayLevelEmphasis [NUMERICAL]
# 	96 : GrayLevelNonUniformity [NUMERICAL]
# 	85 : SmallDependenceLowGrayLevelEmphasis [NUMERICAL]
# 	69 : GrayLevelVariance [NUMERICAL]
# 	68 : SmallDependenceHighGrayLevelEmphasis [NUMERICAL]
# 	50 : DependenceVariance [NUMERICAL]
# 	48 : LargeDependenceLowGrayLevelEmphasis [NUMERICAL]
# 	39 : LowGrayLevelEmphasis [NUMERICAL]
# 	34 : LargeDependenceEmphasis [NUMERICAL]
# 	14 : DependenceNonUniformity [NUMERICAL]
# 	13 : DependenceNonUniformityNormalized [NUMERICAL]
#
# Attribute in nodes with depth <= 3:
# 	285 : LargeDependenceHighGrayLevelEmphasis [NUMERICAL]
# 	268 : DependenceEntropy [NUMERICAL]
# 	210 : HighGrayLevelEmphasis [NUMERICAL]
# 	199 : SmallDependenceEmphasis [NUMERICAL]
# 	184 : GrayLevelVariance [NUMERICAL]
# 	170 : SmallDependenceLowGrayLevelEmphasis [NUMERICAL]
# 	158 : GrayLevelNonUniformity [NUMERICAL]
# 	156 : SmallDependenceHighGrayLevelEmphasis [NUMERICAL]
# 	112 : DependenceVariance [NUMERICAL]
# 	109 : LargeDependenceLowGrayLevelEmphasis [NUMERICAL]
# 	83 : LowGrayLevelEmphasis [NUMERICAL]
# 	74 : LargeDependenceEmphasis [NUMERICAL]
# 	34 : DependenceNonUniformityNormalized [NUMERICAL]
# 	30 : DependenceNonUniformity [NUMERICAL]
#
# Attribute in nodes with depth <= 5:
# 	510 : LargeDependenceHighGrayLevelEmphasis [NUMERICAL]
# 	469 : DependenceEntropy [NUMERICAL]
# 	391 : HighGrayLevelEmphasis [NUMERICAL]
# 	373 : SmallDependenceEmphasis [NUMERICAL]
# 	365 : GrayLevelVariance [NUMERICAL]
# 	334 : SmallDependenceLowGrayLevelEmphasis [NUMERICAL]
# 	324 : SmallDependenceHighGrayLevelEmphasis [NUMERICAL]
# 	303 : GrayLevelNonUniformity [NUMERICAL]
# 	222 : LargeDependenceLowGrayLevelEmphasis [NUMERICAL]
# 	217 : DependenceVariance [NUMERICAL]
# 	179 : LowGrayLevelEmphasis [NUMERICAL]
# 	162 : LargeDependenceEmphasis [NUMERICAL]
# 	76 : DependenceNonUniformityNormalized [NUMERICAL]
# 	64 : DependenceNonUniformity [NUMERICAL]
#
# Condition type in nodes:
# 	3989 : HigherCondition
# Condition type in nodes with depth <= 0:
# 	150 : HigherCondition
# Condition type in nodes with depth <= 1:
# 	450 : HigherCondition
# Condition type in nodes with depth <= 2:
# 	1014 : HigherCondition
# Condition type in nodes with depth <= 3:
# 	2072 : HigherCondition
# Condition type in nodes with depth <= 5:
# 	3989 : HigherCondition
#
# Training logs:
# Number of iteration to final model: 150
# 	Iter:1 train-loss:1.276704 valid-loss:1.277690  train-accuracy:0.845601 valid-accuracy:0.839604
# 	Iter:2 train-loss:1.184974 valid-loss:1.186040  train-accuracy:0.858938 valid-accuracy:0.851532
# 	Iter:3 train-loss:1.106970 valid-loss:1.107542  train-accuracy:0.867160 valid-accuracy:0.866543
# 	Iter:4 train-loss:1.043322 valid-loss:1.043123  train-accuracy:0.864017 valid-accuracy:0.858249
# 	Iter:5 train-loss:0.987331 valid-loss:0.988032  train-accuracy:0.872868 valid-accuracy:0.869971
# 	Iter:6 train-loss:0.936983 valid-loss:0.937069  train-accuracy:0.875479 valid-accuracy:0.873192
# 	Iter:16 train-loss:0.660952 valid-loss:0.667587  train-accuracy:0.891177 valid-accuracy:0.887655
# 	Iter:26 train-loss:0.555777 valid-loss:0.576093  train-accuracy:0.898389 valid-accuracy:0.890123
# 	Iter:36 train-loss:0.505183 valid-loss:0.539934  train-accuracy:0.904469 valid-accuracy:0.893893
# 	Iter:46 train-loss:0.475212 valid-loss:0.521092  train-accuracy:0.908993 valid-accuracy:0.894921
# 	Iter:56 train-loss:0.453404 valid-loss:0.510995  train-accuracy:0.911855 valid-accuracy:0.897800
# 	Iter:66 train-loss:0.434557 valid-loss:0.503427  train-accuracy:0.914375 valid-accuracy:0.896155
# 	Iter:76 train-loss:0.420494 valid-loss:0.498232  train-accuracy:0.917115 valid-accuracy:0.896086
# 	Iter:86 train-loss:0.408153 valid-loss:0.492814  train-accuracy:0.919362 valid-accuracy:0.897800
# 	Iter:96 train-loss:0.398991 valid-loss:0.491785  train-accuracy:0.921920 valid-accuracy:0.898348
# 	Iter:106 train-loss:0.389611 valid-loss:0.489879  train-accuracy:0.923499 valid-accuracy:0.899171
# 	Iter:116 train-loss:0.379120 valid-loss:0.487419  train-accuracy:0.925496 valid-accuracy:0.898897
# 	Iter:126 train-loss:0.371567 valid-loss:0.485875  train-accuracy:0.927902 valid-accuracy:0.898417
# 	Iter:136 train-loss:0.364381 valid-loss:0.484692  train-accuracy:0.929830 valid-accuracy:0.900131
# 	Iter:146 train-loss:0.356166 valid-loss:0.482666  train-accuracy:0.931895 valid-accuracy:0.901090
# 	Iter:156 train-loss:0.349304 valid-loss:0.482354  train-accuracy:0.933587 valid-accuracy:0.900747
# 	Iter:166 train-loss:0.342552 valid-loss:0.482631  train-accuracy:0.935819 valid-accuracy:0.901501
# 	Iter:176 train-loss:0.335796 valid-loss:0.484625  train-accuracy:0.936548 valid-accuracy:0.899788

# %%
# Model features
model.make_inspector().features()
# Out:
# ["DependenceEntropy" (1; #0),
#  "DependenceNonUniformity" (1; #1),
#  "DependenceNonUniformityNormalized" (1; #2),
#  "DependenceVariance" (1; #3),
#  "GrayLevelNonUniformity" (1; #4),
#  "GrayLevelVariance" (1; #5),
#  "HighGrayLevelEmphasis" (1; #6),
#  "LargeDependenceEmphasis" (1; #7),
#  "LargeDependenceHighGrayLevelEmphasis" (1; #8),
#  "LargeDependenceLowGrayLevelEmphasis" (1; #9),
#  "LowGrayLevelEmphasis" (1; #10),
#  "SmallDependenceEmphasis" (1; #11),
#  "SmallDependenceHighGrayLevelEmphasis" (1; #12),
#  "SmallDependenceLowGrayLevelEmphasis" (1; #13)]

# %%
# Feature importance
model.make_inspector().variable_importances()
# Out:
# {'INV_MEAN_MIN_DEPTH': [("LargeDependenceHighGrayLevelEmphasis" (1; #8),
#    0.3099874827441114),
#   ("DependenceEntropy" (1; #0), 0.23085652558709485),
#   ("GrayLevelNonUniformity" (1; #4), 0.21453583410651972),
#   ("HighGrayLevelEmphasis" (1; #6), 0.21258899074584123),
#   ("SmallDependenceLowGrayLevelEmphasis" (1; #13), 0.20720091158519122),
#   ("SmallDependenceEmphasis" (1; #11), 0.20683697187496064),
#   ("GrayLevelVariance" (1; #5), 0.19686496509406345),
#   ("SmallDependenceHighGrayLevelEmphasis" (1; #12), 0.19518298732766196),
#   ("LargeDependenceLowGrayLevelEmphasis" (1; #9), 0.18769993191474174),
#   ("DependenceVariance" (1; #3), 0.18709318548655346),
#   ("LowGrayLevelEmphasis" (1; #10), 0.18023156111751112),
#   ("LargeDependenceEmphasis" (1; #7), 0.17895783622216152),
#   ("DependenceNonUniformityNormalized" (1; #2), 0.17401990023886804),
#   ("DependenceNonUniformity" (1; #1), 0.17401729838056823)],
#  'NUM_AS_ROOT': [("LargeDependenceHighGrayLevelEmphasis" (1; #8), 71.0),
#   ("GrayLevelNonUniformity" (1; #4), 19.0),
#   ("DependenceEntropy" (1; #0), 17.0),
#   ("HighGrayLevelEmphasis" (1; #6), 17.0),
#   ("SmallDependenceLowGrayLevelEmphasis" (1; #13), 10.0),
#   ("GrayLevelVariance" (1; #5), 7.0),
#   ("LargeDependenceLowGrayLevelEmphasis" (1; #9), 4.0),
#   ("DependenceVariance" (1; #3), 3.0),
#   ("SmallDependenceEmphasis" (1; #11), 1.0),
#   ("SmallDependenceHighGrayLevelEmphasis" (1; #12), 1.0)],
#  'SUM_SCORE': [("HighGrayLevelEmphasis" (1; #6), 21975.662174190024),
#   ("LargeDependenceHighGrayLevelEmphasis" (1; #8), 14161.45169636093),
#   ("DependenceEntropy" (1; #0), 11292.88501404727),
#   ("SmallDependenceEmphasis" (1; #11), 10343.279032042969),
#   ("SmallDependenceLowGrayLevelEmphasis" (1; #13), 5393.450646522772),
#   ("GrayLevelNonUniformity" (1; #4), 2418.4697685537903),
#   ("LowGrayLevelEmphasis" (1; #10), 2211.8573473995752),
#   ("SmallDependenceHighGrayLevelEmphasis" (1; #12), 2085.154348814824),
#   ("GrayLevelVariance" (1; #5), 1570.6668652978726),
#   ("DependenceVariance" (1; #3), 1497.6599186442986),
#   ("LargeDependenceLowGrayLevelEmphasis" (1; #9), 1317.5273205518938),
#   ("LargeDependenceEmphasis" (1; #7), 556.4410467896911),
#   ("DependenceNonUniformityNormalized" (1; #2), 222.75224734858807),
#   ("DependenceNonUniformity" (1; #1), 169.32104750968074)],
#  'NUM_NODES': [("LargeDependenceHighGrayLevelEmphasis" (1; #8), 510.0),
#   ("DependenceEntropy" (1; #0), 469.0),
#   ("HighGrayLevelEmphasis" (1; #6), 391.0),
#   ("SmallDependenceEmphasis" (1; #11), 373.0),
#   ("GrayLevelVariance" (1; #5), 365.0),
#   ("SmallDependenceLowGrayLevelEmphasis" (1; #13), 334.0),
#   ("SmallDependenceHighGrayLevelEmphasis" (1; #12), 324.0),
#   ("GrayLevelNonUniformity" (1; #4), 303.0),
#   ("LargeDependenceLowGrayLevelEmphasis" (1; #9), 222.0),
#   ("DependenceVariance" (1; #3), 217.0),
#   ("LowGrayLevelEmphasis" (1; #10), 179.0),
#   ("LargeDependenceEmphasis" (1; #7), 162.0),
#   ("DependenceNonUniformityNormalized" (1; #2), 76.0),
#   ("DependenceNonUniformity" (1; #1), 64.0)]}

# %%
# Model self evaluation
model.make_inspector().evaluation()
# Out:
# Evaluation(num_examples=None, accuracy=0.9013643860816956, loss=0.481765478849411, rmse=None, ndcg=None, aucs=None, auuc=None, qini=None)

# %%
logs = model.make_inspector().training_logs()

plt.figure(figsize=(12, 4))
plt.subplot(1, 2, 1)
plt.plot([log.num_trees for log in logs], [log.evaluation.accuracy for log in logs])
plt.xlabel("Number of trees")
plt.ylabel("Accuracy (out-of-bag)")
plt.subplot(1, 2, 2)
plt.plot([log.num_trees for log in logs], [log.evaluation.loss for log in logs])
plt.xlabel("Number of trees")
plt.ylabel("Logloss (out-of-bag)")
plt.show()

# %% [markdown]
# Calculate the score of our hold-out validation dataset

# %%
predictions = model.predict(val_ds)
y_true      = validation_data["label"]

from sklearn.metrics import roc_auc_score
ROC_AUC = roc_auc_score(y_true, predictions)
print("The ROC AUC score is %.5f" % ROC_AUC )
# Out:
#  1/12 [=>............................] - ETA: 0s
# 12/12 [==============================] - 0s 4ms/step
# The ROC AUC score is 0.95545

# %%
# Compute binary classification metrics with sklearn
import numpy as np
from sklearn.metrics import (
    accuracy_score,
    precision_score,
    recall_score,
    f1_score,
    roc_auc_score,
    average_precision_score,
    confusion_matrix,
    classification_report,
    matthews_corrcoef,
    log_loss,
    brier_score_loss,
)

# Get predictions (probabilities or class labels)
preds = model.predict(test_ds)
# If model outputs probabilities, convert to labels by threshold 0.5
if preds.ndim == 2:
    # For TFDF classification, preds may be class probabilities with shape (N, 2)
    if preds.shape[1] == 2:
        pos_probs = preds[:, 1]
    else:
        # If single-probability column (positive class)
        pos_probs = preds[:, -1]
    y_pred = (pos_probs >= 0.5).astype(int)
else:
    # Already class labels
    y_pred = preds.astype(int)
    pos_probs = None

# Ground truth labels (must be 0/1 integers)
y_true = test_data["label"].astype(int).to_numpy()

# Core metrics
metrics = {}
metrics["accuracy"] = accuracy_score(y_true, y_pred)
metrics["precision"] = precision_score(y_true, y_pred, zero_division=0)
metrics["recall"] = recall_score(y_true, y_pred, zero_division=0)
metrics["f1"] = f1_score(y_true, y_pred, zero_division=0)
metrics["mcc"] = matthews_corrcoef(y_true, y_pred)

# Probabilistic metrics (only if we have probabilities)
if pos_probs is not None:
    metrics["roc_auc"] = roc_auc_score(y_true, pos_probs)
    metrics["pr_auc"] = average_precision_score(y_true, pos_probs)
    metrics["log_loss"] = log_loss(y_true, pos_probs, labels=[0,1])
    metrics["brier_score"] = brier_score_loss(y_true, pos_probs)

# Confusion matrix and detailed report
cm = confusion_matrix(y_true, y_pred, labels=[0,1])
report = classification_report(y_true, y_pred, digits=4)

print("Sklearn binary metrics:")
for k, v in metrics.items():
    print(f"{k}: {v:.4f}")
print("\nConfusion matrix:\n", cm)
print("\nClassification report:\n", report)
# Out:
#  1/23 [>.............................] - ETA: 1s
# 15/23 [==================>...........] - ETA: 0s
# 23/23 [==============================] - 0s 4ms/step
# Sklearn binary metrics:
# accuracy: 0.9174
# precision: 0.4672
# recall: 0.8584
# f1: 0.6051
# mcc: 0.5960
# roc_auc: 0.9597
# pr_auc: 0.7971
# log_loss: 0.2062
# brier_score: 0.0599
#
# Confusion matrix:
#  [[19227  1625]
#  [  235  1425]]
#
# Classification report:
#                precision    recall  f1-score   support
#
#            0     0.9879    0.9221    0.9539     20852
#            1     0.4672    0.8584    0.6051      1660
#
#     accuracy                         0.9174     22512
#    macro avg     0.7276    0.8903    0.7795     22512
# weighted avg     0.9495    0.9174    0.9281     22512
