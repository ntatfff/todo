# %%
# Import packages and modules
import numpy  as np
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow_decision_forests as tfdf

from sklearn.model_selection import train_test_split
# Out:
# 2026-07-04 09:14:16.663974: I tensorflow/core/util/port.cc:113] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2026-07-04 09:14:16.703325: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2026-07-04 09:14:22.699098: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
# Check the version of TensorFlow Decision Forests
print("Found TensorFlow Decision Forests v" + tfdf.__version__)
# Out:
# Found TensorFlow Decision Forests v1.9.1

# %%
datasetPath = 'dataset/firstorder/kernel5-radius5/dataset.csv'

# %%
# Parameters
datasetPath = "dataset/ngtdm/kernel5-radius5/200.dataset.csv"

# %%
# train/validation/test = 70/10/20
dataset = pd.read_csv(datasetPath)

train_data, temp_data = train_test_split(dataset, test_size=0.3, random_state=42)
validation_data, test_data = train_test_split(temp_data, test_size=2/3, random_state=42)

# %%
from sklearn.utils.class_weight import compute_class_weight

# tinh class weight tren tap train
classes = np.array([0, 1])
weights = compute_class_weight(class_weight="balanced", classes=classes, y=train_data["label"])
class_weight = {0: weights[0], 1: weights[1]}

# gan sample_weight cho tung dong
train_data["sample_weight"] = train_data["label"].map(class_weight)
validation_data["sample_weight"] = validation_data["label"].map(class_weight)
test_data["sample_weight"] = test_data["label"].map(class_weight)

# Convert the dataset into a TensorFlow dataset.
train_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    train_data, label="label", weight="sample_weight"
)         
val_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    validation_data, label="label", weight="sample_weight"
)
test_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    test_data, label="label", weight="sample_weight"
)
# Out:
# 2026-07-04 09:14:34.671069: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:984] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2026-07-04 09:14:34.672714: W tensorflow/core/common_runtime/gpu/gpu_device.cc:2251] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...

# %%
import keras

# %%
# %%time

# Train a Gradient Boosted Trees model.
model = tfdf.keras.GradientBoostedTreesModel()

# Add evaluation metrics
model.compile(
    metrics=["accuracy"]
)
model.fit(x=train_ds)

# # Train a Gradient Boosted Trees model.
# model = tfdf.keras.GradientBoostedTreesModel(num_trees=1500)
# model.fit(train_ds)
# Out:
# Use /tmp/tmpftxkxzrn as temporary training directory
# Reading training dataset...
# [WARNING 26-07-04 09:14:34.7780 UTC gradient_boosted_trees.cc:1840] "goss_alpha" set but "sampling_method" not equal to "GOSS".
# [WARNING 26-07-04 09:14:34.7781 UTC gradient_boosted_trees.cc:1851] "goss_beta" set but "sampling_method" not equal to "GOSS".
# [WARNING 26-07-04 09:14:34.7781 UTC gradient_boosted_trees.cc:1865] "selective_gradient_boosting_ratio" set but "sampling_method" not equal to "SELGB".
# Training dataset read in 0:00:02.675625. Found 157360 examples.
# Training model...
# Model trained in 0:00:18.377845
# Compiling model...
# [INFO 26-07-04 09:14:55.8408 UTC kernel.cc:1233] Loading model from path /tmp/tmpftxkxzrn/model/ with prefix 09a71e1e62854bd9
# [INFO 26-07-04 09:14:55.8520 UTC quick_scorer_extended.cc:911] The binary was compiled without AVX2 support, but your CPU supports it. Enable it for faster model inference.
# [INFO 26-07-04 09:14:55.8527 UTC abstract_model.cc:1362] Engine "GradientBoostedTreesQuickScorerExtended" built
# [INFO 26-07-04 09:14:55.8527 UTC kernel.cc:1061] Use fast generic engine
# Model compiled.
# CPU times: user 1min 11s, sys: 1.09 s, total: 1min 12s
# Wall time: 24 s

# %%
# Evaluate the model
evaluate = model.evaluate(val_ds, return_dict=True)
print()

for name, value in evaluate.items():
    print(f"{name}: {value:.4f}")
# Out:
# WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
#  1/23 [>.............................] - ETA: 1:00 - loss: 0.0000e+00 - accuracy: 0.8780
# 18/23 [======================>.......] - ETA: 0s - loss: 0.0000e+00 - accuracy: 0.8749
# 23/23 [==============================] - 3s 3ms/step - loss: 0.0000e+00 - accuracy: 0.8745
# loss: 0.0000
# accuracy: 0.8745

# %%
# Model Summary
model.summary()
# Out:
# Model: "gradient_boosted_trees_model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
# =================================================================
# Total params: 1 (1.00 Byte)
# Trainable params: 0 (0.00 Byte)
# Non-trainable params: 1 (1.00 Byte)
# _________________________________________________________________
# Type: "GRADIENT_BOOSTED_TREES"
# Task: CLASSIFICATION
# Label: "__LABEL"
#
# Input Features (5):
# 	Busyness
# 	Coarseness
# 	Complexity
# 	Contrast
# 	Strength
#
# Trained with weights
#
# Variable Importance: INV_MEAN_MIN_DEPTH:
#     1.   "Busyness"  0.341119 ################
#     2.   "Contrast"  0.296271 ##########
#     3. "Complexity"  0.264822 ######
#     4. "Coarseness"  0.245286 ###
#     5.   "Strength"  0.214330
#
# Variable Importance: NUM_AS_ROOT:
#     1.   "Busyness" 78.000000 ################
#     2.   "Contrast" 76.000000 ###############
#     3. "Coarseness" 44.000000 ########
#     4. "Complexity" 22.000000 ####
#     5.   "Strength"  3.000000
#
# Variable Importance: NUM_NODES:
#     1.   "Busyness" 1752.000000 ################
#     2.   "Contrast" 1130.000000 ###
#     3. "Complexity" 1072.000000 ##
#     4. "Coarseness" 1048.000000 ##
#     5.   "Strength" 947.000000
#
# Variable Importance: SUM_SCORE:
#     1. "Coarseness" 65649.223826 ################
#     2.   "Busyness" 34381.655601 #######
#     3. "Complexity" 11744.940851 #
#     4.   "Contrast" 7125.859969
#     5.   "Strength" 5902.464083
#
#
#
# Loss: BINOMIAL_LOG_LIKELIHOOD
# Validation loss value: 0.662857
# Number of trees per iteration: 1
# Node format: NOT_SET
# Number of trees: 223
# Total number of nodes: 12121
#
# Number of nodes by tree:
# Count: 223 Average: 54.3543 StdDev: 7.89477
# Min: 29 Max: 63 Ignored: 0
# ----------------------------------------------
# [ 29, 30)  1   0.45%   0.45%
# [ 30, 32)  0   0.00%   0.45%
# [ 32, 34)  2   0.90%   1.35%
# [ 34, 36)  3   1.35%   2.69% #
# [ 36, 37)  0   0.00%   2.69%
# [ 37, 39)  0   0.00%   2.69%
# [ 39, 41)  9   4.04%   6.73% ##
# [ 41, 43)  9   4.04%  10.76% ##
# [ 43, 44)  5   2.24%  13.00% #
# [ 44, 46)  5   2.24%  15.25% #
# [ 46, 48) 14   6.28%  21.52% ###
# [ 48, 50) 15   6.73%  28.25% ####
# [ 50, 51)  0   0.00%  28.25%
# [ 51, 53) 15   6.73%  34.98% ####
# [ 53, 55)  9   4.04%  39.01% ##
# [ 55, 57) 19   8.52%  47.53% #####
# [ 57, 58) 21   9.42%  56.95% #####
# [ 58, 60) 27  12.11%  69.06% #######
# [ 60, 62) 28  12.56%  81.61% #######
# [ 62, 63] 41  18.39% 100.00% ##########
#
# Depth by leafs:
# Count: 6172 Average: 4.88658 StdDev: 0.415709
# Min: 2 Max: 5 Ignored: 0
# ----------------------------------------------
# [ 2, 3)   41   0.66%   0.66%
# [ 3, 4)  100   1.62%   2.28%
# [ 4, 5)  377   6.11%   8.39% #
# [ 5, 5] 5654  91.61% 100.00% ##########
#
# Number of training obs by leaf:
# Count: 6172 Average: 5118.52 StdDev: 17916.5
# Min: 5 Max: 140535 Ignored: 0
# ----------------------------------------------
# [      5,   7031) 5451  88.32%  88.32% ##########
# [   7031,  14058)  244   3.95%  92.27%
# [  14058,  21084)  133   2.15%  94.43%
# [  21084,  28111)   63   1.02%  95.45%
# [  28111,  35137)   33   0.53%  95.98%
# [  35137,  42164)   36   0.58%  96.57%
# [  42164,  49190)   20   0.32%  96.89%
# [  49190,  56217)   14   0.23%  97.12%
# [  56217,  63243)   18   0.29%  97.41%
# [  63243,  70270)   12   0.19%  97.60%
# [  70270,  77297)   17   0.28%  97.88%
# [  77297,  84323)    4   0.06%  97.94%
# [  84323,  91350)   17   0.28%  98.22%
# [  91350,  98376)   18   0.29%  98.51%
# [  98376, 105403)   16   0.26%  98.77%
# [ 105403, 112429)   15   0.24%  99.01%
# [ 112429, 119456)   15   0.24%  99.25%
# [ 119456, 126482)   12   0.19%  99.45%
# [ 126482, 133509)   13   0.21%  99.66%
# [ 133509, 140535]   21   0.34% 100.00%
#
# Attribute in nodes:
# 	1752 : Busyness [NUMERICAL]
# 	1130 : Contrast [NUMERICAL]
# 	1072 : Complexity [NUMERICAL]
# 	1048 : Coarseness [NUMERICAL]
# 	947 : Strength [NUMERICAL]
#
# Attribute in nodes with depth <= 0:
# 	78 : Busyness [NUMERICAL]
# 	76 : Contrast [NUMERICAL]
# 	44 : Coarseness [NUMERICAL]
# 	22 : Complexity [NUMERICAL]
# 	3 : Strength [NUMERICAL]
#
# Attribute in nodes with depth <= 1:
# 	194 : Contrast [NUMERICAL]
# 	177 : Busyness [NUMERICAL]
# 	141 : Complexity [NUMERICAL]
# 	103 : Coarseness [NUMERICAL]
# 	54 : Strength [NUMERICAL]
#
# Attribute in nodes with depth <= 2:
# 	430 : Busyness [NUMERICAL]
# 	365 : Contrast [NUMERICAL]
# 	310 : Complexity [NUMERICAL]
# 	239 : Coarseness [NUMERICAL]
# 	176 : Strength [NUMERICAL]
#
# Attribute in nodes with depth <= 3:
# 	867 : Busyness [NUMERICAL]
# 	669 : Contrast [NUMERICAL]
# 	588 : Complexity [NUMERICAL]
# 	525 : Coarseness [NUMERICAL]
# 	473 : Strength [NUMERICAL]
#
# Attribute in nodes with depth <= 5:
# 	1752 : Busyness [NUMERICAL]
# 	1130 : Contrast [NUMERICAL]
# 	1072 : Complexity [NUMERICAL]
# 	1048 : Coarseness [NUMERICAL]
# 	947 : Strength [NUMERICAL]
#
# Condition type in nodes:
# 	5949 : HigherCondition
# Condition type in nodes with depth <= 0:
# 	223 : HigherCondition
# Condition type in nodes with depth <= 1:
# 	669 : HigherCondition
# Condition type in nodes with depth <= 2:
# 	1520 : HigherCondition
# Condition type in nodes with depth <= 3:
# 	3122 : HigherCondition
# Condition type in nodes with depth <= 5:
# 	5949 : HigherCondition
#
# Training logs:
# Number of iteration to final model: 223
# 	Iter:1 train-loss:1.297300 valid-loss:1.297126  train-accuracy:0.801866 valid-accuracy:0.801882
# 	Iter:2 train-loss:1.223912 valid-loss:1.223860  train-accuracy:0.819651 valid-accuracy:0.819924
# 	Iter:3 train-loss:1.161587 valid-loss:1.162271  train-accuracy:0.820099 valid-accuracy:0.820459
# 	Iter:4 train-loss:1.109602 valid-loss:1.110232  train-accuracy:0.820713 valid-accuracy:0.818446
# 	Iter:5 train-loss:1.064164 valid-loss:1.064803  train-accuracy:0.821386 valid-accuracy:0.819227
# 	Iter:6 train-loss:1.026628 valid-loss:1.026998  train-accuracy:0.821820 valid-accuracy:0.818767
# 	Iter:16 train-loss:0.817938 valid-loss:0.825875  train-accuracy:0.832555 valid-accuracy:0.827756
# 	Iter:26 train-loss:0.739878 valid-loss:0.754537  train-accuracy:0.843426 valid-accuracy:0.839371
# 	Iter:36 train-loss:0.696174 valid-loss:0.716962  train-accuracy:0.850984 valid-accuracy:0.843756
# 	Iter:46 train-loss:0.672734 valid-loss:0.701733  train-accuracy:0.854624 valid-accuracy:0.846601
# 	Iter:56 train-loss:0.658911 valid-loss:0.694210  train-accuracy:0.856870 valid-accuracy:0.847636
# 	Iter:66 train-loss:0.644364 valid-loss:0.684261  train-accuracy:0.859633 valid-accuracy:0.849857
# 	Iter:76 train-loss:0.634900 valid-loss:0.678858  train-accuracy:0.861153 valid-accuracy:0.852372
# 	Iter:86 train-loss:0.626010 valid-loss:0.677147  train-accuracy:0.863146 valid-accuracy:0.851194
# 	Iter:96 train-loss:0.619098 valid-loss:0.675084  train-accuracy:0.865731 valid-accuracy:0.851708
# 	Iter:106 train-loss:0.610892 valid-loss:0.672341  train-accuracy:0.867377 valid-accuracy:0.852326
# 	Iter:116 train-loss:0.604230 valid-loss:0.670122  train-accuracy:0.869493 valid-accuracy:0.851977
# 	Iter:126 train-loss:0.597674 valid-loss:0.668387  train-accuracy:0.870869 valid-accuracy:0.852423
# 	Iter:136 train-loss:0.591880 valid-loss:0.667365  train-accuracy:0.872985 valid-accuracy:0.851073
# 	Iter:146 train-loss:0.587282 valid-loss:0.667740  train-accuracy:0.874308 valid-accuracy:0.851622
# 	Iter:156 train-loss:0.581609 valid-loss:0.666021  train-accuracy:0.876244 valid-accuracy:0.852753
# 	Iter:166 train-loss:0.576417 valid-loss:0.664218  train-accuracy:0.877817 valid-accuracy:0.853597
# 	Iter:176 train-loss:0.572566 valid-loss:0.663898  train-accuracy:0.878461 valid-accuracy:0.853008
# 	Iter:186 train-loss:0.568629 valid-loss:0.664195  train-accuracy:0.879023 valid-accuracy:0.853488
# 	Iter:196 train-loss:0.564324 valid-loss:0.663830  train-accuracy:0.880034 valid-accuracy:0.853728
# 	Iter:206 train-loss:0.559805 valid-loss:0.663641  train-accuracy:0.880933 valid-accuracy:0.854502
# 	Iter:216 train-loss:0.554720 valid-loss:0.663099  train-accuracy:0.882703 valid-accuracy:0.854742
# 	Iter:226 train-loss:0.551004 valid-loss:0.663607  train-accuracy:0.883355 valid-accuracy:0.855394
# 	Iter:236 train-loss:0.546944 valid-loss:0.664149  train-accuracy:0.884530 valid-accuracy:0.855134
# 	Iter:246 train-loss:0.542848 valid-loss:0.663328  train-accuracy:0.885696 valid-accuracy:0.855511

# %%
# Model features
model.make_inspector().features()
# Out:
# ["Busyness" (1; #0),
#  "Coarseness" (1; #1),
#  "Complexity" (1; #2),
#  "Contrast" (1; #3),
#  "Strength" (1; #4)]

# %%
# Feature importance
model.make_inspector().variable_importances()
# Out:
# {'INV_MEAN_MIN_DEPTH': [("Busyness" (1; #0), 0.34111899230807347),
#   ("Contrast" (1; #3), 0.29627103140483824),
#   ("Complexity" (1; #2), 0.26482194816226995),
#   ("Coarseness" (1; #1), 0.2452858378772981),
#   ("Strength" (1; #4), 0.21433008826286282)],
#  'NUM_AS_ROOT': [("Busyness" (1; #0), 78.0),
#   ("Contrast" (1; #3), 76.0),
#   ("Coarseness" (1; #1), 44.0),
#   ("Complexity" (1; #2), 22.0),
#   ("Strength" (1; #4), 3.0)],
#  'SUM_SCORE': [("Coarseness" (1; #1), 65649.22382639229),
#   ("Busyness" (1; #0), 34381.655600551996),
#   ("Complexity" (1; #2), 11744.940851133322),
#   ("Contrast" (1; #3), 7125.859968955281),
#   ("Strength" (1; #4), 5902.464083008568)],
#  'NUM_NODES': [("Busyness" (1; #0), 1752.0),
#   ("Contrast" (1; #3), 1130.0),
#   ("Complexity" (1; #2), 1072.0),
#   ("Coarseness" (1; #1), 1048.0),
#   ("Strength" (1; #4), 947.0)]}

# %%
# Model self evaluation
model.make_inspector().evaluation()
# Out:
# Evaluation(num_examples=None, accuracy=0.8557571768760681, loss=0.6628573536872864, rmse=None, ndcg=None, aucs=None, auuc=None, qini=None)

# %%
logs = model.make_inspector().training_logs()

plt.figure(figsize=(12, 4))
plt.subplot(1, 2, 1)
plt.plot([log.num_trees for log in logs], [log.evaluation.accuracy for log in logs])
plt.xlabel("Number of trees")
plt.ylabel("Accuracy (out-of-bag)")
plt.subplot(1, 2, 2)
plt.plot([log.num_trees for log in logs], [log.evaluation.loss for log in logs])
plt.xlabel("Number of trees")
plt.ylabel("Logloss (out-of-bag)")
plt.show()

# %% [markdown]
# Calculate the score of our hold-out validation dataset

# %%
predictions = model.predict(val_ds)
y_true      = validation_data["label"]

from sklearn.metrics import roc_auc_score
ROC_AUC = roc_auc_score(y_true, predictions)
print("The ROC AUC score is %.5f" % ROC_AUC )
# Out:
#  1/23 [>.............................] - ETA: 1s
# 19/23 [=======================>......] - ETA: 0s
# 23/23 [==============================] - 0s 3ms/step
# The ROC AUC score is 0.93174

# %%
# Compute binary classification metrics with sklearn
import numpy as np
from sklearn.metrics import (
    accuracy_score,
    precision_score,
    recall_score,
    f1_score,
    roc_auc_score,
    average_precision_score,
    confusion_matrix,
    classification_report,
    matthews_corrcoef,
    log_loss,
    brier_score_loss,
)

# Get predictions (probabilities or class labels)
preds = model.predict(test_ds)
# If model outputs probabilities, convert to labels by threshold 0.5
if preds.ndim == 2:
    # For TFDF classification, preds may be class probabilities with shape (N, 2)
    if preds.shape[1] == 2:
        pos_probs = preds[:, 1]
    else:
        # If single-probability column (positive class)
        pos_probs = preds[:, -1]
    y_pred = (pos_probs >= 0.5).astype(int)
else:
    # Already class labels
    y_pred = preds.astype(int)
    pos_probs = None

# Ground truth labels (must be 0/1 integers)
y_true = test_data["label"].astype(int).to_numpy()

# Core metrics
metrics = {}
metrics["accuracy"] = accuracy_score(y_true, y_pred)
metrics["precision"] = precision_score(y_true, y_pred, zero_division=0)
metrics["recall"] = recall_score(y_true, y_pred, zero_division=0)
metrics["f1"] = f1_score(y_true, y_pred, zero_division=0)
metrics["mcc"] = matthews_corrcoef(y_true, y_pred)

# Probabilistic metrics (only if we have probabilities)
if pos_probs is not None:
    metrics["roc_auc"] = roc_auc_score(y_true, pos_probs)
    metrics["pr_auc"] = average_precision_score(y_true, pos_probs)
    metrics["log_loss"] = log_loss(y_true, pos_probs, labels=[0,1])
    metrics["brier_score"] = brier_score_loss(y_true, pos_probs)

# Confusion matrix and detailed report
cm = confusion_matrix(y_true, y_pred, labels=[0,1])
report = classification_report(y_true, y_pred, digits=4)

print("Sklearn binary metrics:")
for k, v in metrics.items():
    print(f"{k}: {v:.4f}")
print("\nConfusion matrix:\n", cm)
print("\nClassification report:\n", report)
# Out:
#  1/45 [..............................] - ETA: 2s
# 20/45 [============>.................] - ETA: 0s
# 38/45 [========================>.....] - ETA: 0s
# 45/45 [==============================] - 0s 3ms/step
# Sklearn binary metrics:
# accuracy: 0.8730
# precision: 0.3207
# recall: 0.8347
# f1: 0.4633
# mcc: 0.4675
# roc_auc: 0.9324
# pr_auc: 0.6291
# log_loss: 0.3015
# brier_score: 0.0928
#
# Confusion matrix:
#  [[36786  5222]
#  [  488  2465]]
#
# Classification report:
#                precision    recall  f1-score   support
#
#            0     0.9869    0.8757    0.9280     42008
#            1     0.3207    0.8347    0.4633      2953
#
#     accuracy                         0.8730     44961
#    macro avg     0.6538    0.8552    0.6957     44961
# weighted avg     0.9431    0.8730    0.8975     44961
