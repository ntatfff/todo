# %%
# Import packages and modules
import numpy  as np
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow_decision_forests as tfdf

from sklearn.model_selection import train_test_split
# Out:
# 2026-07-04 07:45:29.215167: I tensorflow/core/util/port.cc:113] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2026-07-04 07:45:29.257975: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2026-07-04 07:45:33.519866: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
# Check the version of TensorFlow Decision Forests
print("Found TensorFlow Decision Forests v" + tfdf.__version__)
# Out:
# Found TensorFlow Decision Forests v1.9.1

# %%
datasetPath = 'dataset/firstorder/kernel5-radius5/dataset.csv'

# %%
# Parameters
datasetPath = "dataset/firstorder/kernel5-radius5/400.dataset.csv"

# %%
# train/validation/test = 70/10/20
dataset = pd.read_csv(datasetPath)

train_data, temp_data = train_test_split(dataset, test_size=0.3, random_state=42)
validation_data, test_data = train_test_split(temp_data, test_size=2/3, random_state=42)

# %%
from sklearn.utils.class_weight import compute_class_weight

# tinh class weight tren tap train
classes = np.array([0, 1])
weights = compute_class_weight(class_weight="balanced", classes=classes, y=train_data["label"])
class_weight = {0: weights[0], 1: weights[1]}

# gan sample_weight cho tung dong
train_data["sample_weight"] = train_data["label"].map(class_weight)
validation_data["sample_weight"] = validation_data["label"].map(class_weight)
test_data["sample_weight"] = test_data["label"].map(class_weight)

# Convert the dataset into a TensorFlow dataset.
train_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    train_data, label="label", weight="sample_weight"
)         
val_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    validation_data, label="label", weight="sample_weight"
)
test_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    test_data, label="label", weight="sample_weight"
)
# Out:
# 2026-07-04 07:45:47.919486: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:984] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2026-07-04 07:45:47.920957: W tensorflow/core/common_runtime/gpu/gpu_device.cc:2251] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...

# %%
import keras

# %%
# %%time

# Train a Random Forest model.
model = tfdf.keras.RandomForestModel()

# Add evaluation metrics
model.compile(
    metrics=["accuracy"]
)
model.fit(x=train_ds)

# # Train a Gradient Boosted Trees model.
# model = tfdf.keras.GradientBoostedTreesModel(num_trees=1500)
# model.fit(train_ds)
# Out:
# Use /tmp/tmpioiivw1p as temporary training directory
# Reading training dataset...
# Training dataset read in 0:00:03.853853. Found 315417 examples.
# Training model...
# [INFO 26-07-04 07:46:31.3881 UTC kernel.cc:1233] Loading model from path /tmp/tmpioiivw1p/model/ with prefix ac2bba9c196947a0
# [INFO 26-07-04 07:46:34.2372 UTC decision_forest.cc:734] Model loaded with 300 root(s), 1659328 node(s), and 18 input feature(s).
# [INFO 26-07-04 07:46:34.2373 UTC abstract_model.cc:1362] Engine "RandomForestOptPred" built
# [INFO 26-07-04 07:46:34.2373 UTC kernel.cc:1061] Use fast generic engine
# Model trained in 0:00:42.520207
# Compiling model...
# Model compiled.
# CPU times: user 7min 39s, sys: 3.31 s, total: 7min 43s
# Wall time: 51 s

# %%
# Evaluate the model
evaluate = model.evaluate(val_ds, return_dict=True)
print()

for name, value in evaluate.items():
    print(f"{name}: {value:.4f}")
# Out:
# WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
#  1/46 [..............................] - ETA: 2:17 - loss: 0.0000e+00 - accuracy: 0.9030
#  3/46 [>.............................] - ETA: 1s - loss: 0.0000e+00 - accuracy: 0.9017
#  5/46 [==>...........................] - ETA: 1s - loss: 0.0000e+00 - accuracy: 0.9012
#  7/46 [===>..........................] - ETA: 1s - loss: 0.0000e+00 - accuracy: 0.9007
#  9/46 [====>.........................] - ETA: 1s - loss: 0.0000e+00 - accuracy: 0.9036
# 11/46 [======>.......................] - ETA: 1s - loss: 0.0000e+00 - accuracy: 0.9033
# 13/46 [=======>......................] - ETA: 1s - loss: 0.0000e+00 - accuracy: 0.9034
# 15/46 [========>.....................] - ETA: 1s - loss: 0.0000e+00 - accuracy: 0.9031
# 17/46 [==========>...................] - ETA: 1s - loss: 0.0000e+00 - accuracy: 0.9036
# 19/46 [===========>..................] - ETA: 0s - loss: 0.0000e+00 - accuracy: 0.9024
# 21/46 [============>.................] - ETA: 0s - loss: 0.0000e+00 - accuracy: 0.9030
# 23/46 [==============>...............] - ETA: 0s - loss: 0.0000e+00 - accuracy: 0.9036
# 25/46 [===============>..............] - ETA: 0s - loss: 0.0000e+00 - accuracy: 0.9042
# 27/46 [================>.............] - ETA: 0s - loss: 0.0000e+00 - accuracy: 0.9042
# 29/46 [=================>............] - ETA: 0s - loss: 0.0000e+00 - accuracy: 0.9034
# 31/46 [===================>..........] - ETA: 0s - loss: 0.0000e+00 - accuracy: 0.9037
# 33/46 [====================>.........] - ETA: 0s - loss: 0.0000e+00 - accuracy: 0.9039
# 35/46 [=====================>........] - ETA: 0s - loss: 0.0000e+00 - accuracy: 0.9038
# 37/46 [=======================>......] - ETA: 0s - loss: 0.0000e+00 - accuracy: 0.9034
# 39/46 [========================>.....] - ETA: 0s - loss: 0.0000e+00 - accuracy: 0.9027
# 41/46 [=========================>....] - ETA: 0s - loss: 0.0000e+00 - accuracy: 0.9028
# 43/46 [===========================>..] - ETA: 0s - loss: 0.0000e+00 - accuracy: 0.9028
# 45/46 [============================>.] - ETA: 0s - loss: 0.0000e+00 - accuracy: 0.9027
# 46/46 [==============================] - 5s 35ms/step - loss: 0.0000e+00 - accuracy: 0.9027
# loss: 0.0000
# accuracy: 0.9027

# %%
# Model Summary
model.summary()
# Out:
# Model: "random_forest_model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
# =================================================================
# Total params: 1 (1.00 Byte)
# Trainable params: 0 (0.00 Byte)
# Non-trainable params: 1 (1.00 Byte)
# _________________________________________________________________
# Type: "RANDOM_FOREST"
# Task: CLASSIFICATION
# Label: "__LABEL"
#
# Input Features (18):
# 	10Percentile
# 	90Percentile
# 	Energy
# 	Entropy
# 	InterquartileRange
# 	Kurtosis
# 	Maximum
# 	Mean
# 	MeanAbsoluteDeviation
# 	Median
# 	Minimum
# 	Range
# 	RobustMeanAbsoluteDeviation
# 	RootMeanSquared
# 	Skewness
# 	TotalEnergy
# 	Uniformity
# 	Variance
#
# Trained with weights
#
# Variable Importance: INV_MEAN_MIN_DEPTH:
#     1.                        "Mean"  0.147903 ################
#     2.             "RootMeanSquared"  0.139297 ##############
#     3.                      "Energy"  0.131521 ############
#     4.                 "TotalEnergy"  0.127458 ###########
#     5.                     "Minimum"  0.116084 ########
#     6.                "90Percentile"  0.114590 ########
#     7.                     "Maximum"  0.111996 #######
#     8.                       "Range"  0.101130 #####
#     9.                      "Median"  0.100404 #####
#    10.                    "Kurtosis"  0.096578 ####
#    11.          "InterquartileRange"  0.090839 ##
#    12.                "10Percentile"  0.090518 ##
#    13.                    "Skewness"  0.089500 ##
#    14. "RobustMeanAbsoluteDeviation"  0.087730 ##
#    15.                  "Uniformity"  0.083183 #
#    16.       "MeanAbsoluteDeviation"  0.081764
#    17.                    "Variance"  0.081295
#    18.                     "Entropy"  0.078218
#
# Variable Importance: NUM_AS_ROOT:
#     1.            "Mean" 94.000000 ################
#     2. "RootMeanSquared" 64.000000 ##########
#     3.          "Energy" 47.000000 #######
#     4.     "TotalEnergy" 47.000000 #######
#     5.          "Median" 26.000000 ####
#     6.    "90Percentile" 11.000000 #
#     7.    "10Percentile"  8.000000 #
#     8.         "Minimum"  2.000000
#     9.         "Maximum"  1.000000
#
# Variable Importance: NUM_NODES:
#     1.                    "Skewness" 62836.000000 ################
#     2.                     "Maximum" 58614.000000 #############
#     3.                       "Range" 56397.000000 ############
#     4.                    "Kurtosis" 55399.000000 ############
#     5.                  "Uniformity" 49448.000000 ########
#     6.                      "Median" 48925.000000 ########
#     7.                "90Percentile" 46971.000000 #######
#     8.                     "Minimum" 46702.000000 #######
#     9.                     "Entropy" 46575.000000 #######
#    10.                    "Variance" 46223.000000 #######
#    11. "RobustMeanAbsoluteDeviation" 45240.000000 ######
#    12.          "InterquartileRange" 44061.000000 ######
#    13.                "10Percentile" 43322.000000 #####
#    14.       "MeanAbsoluteDeviation" 42524.000000 #####
#    15.                        "Mean" 38724.000000 ###
#    16.                      "Energy" 32556.000000
#    17.             "RootMeanSquared" 32531.000000
#    18.                 "TotalEnergy" 32466.000000
#
# Variable Importance: SUM_SCORE:
#     1.                        "Mean" 5677386.803793 ################
#     2.             "RootMeanSquared" 4879380.666347 #############
#     3.                      "Energy" 4342830.605822 ###########
#     4.                 "TotalEnergy" 4177057.529797 ##########
#     5.                "90Percentile" 3387812.439956 ########
#     6.                     "Maximum" 3196144.265660 #######
#     7.                      "Median" 2630334.610451 #####
#     8.                     "Minimum" 2525553.506216 #####
#     9.                       "Range" 2234520.357333 ####
#    10.                    "Kurtosis" 1956350.660586 ###
#    11.                    "Skewness" 1906273.431540 ###
#    12.                "10Percentile" 1837085.899054 ##
#    13.          "InterquartileRange" 1557979.978750 #
#    14. "RobustMeanAbsoluteDeviation" 1491611.008018 #
#    15.                  "Uniformity" 1291845.367796
#    16.                    "Variance" 1251419.952919
#    17.       "MeanAbsoluteDeviation" 1234304.159238
#    18.                     "Entropy" 1022538.107874
#
#
#
# Winner takes all: true
# Out-of-bag evaluation: accuracy:0.835346 logloss:0.61788
# Number of trees: 300
# Total number of nodes: 1659328
#
# Number of nodes by tree:
# Count: 300 Average: 5531.09 StdDev: 218.135
# Min: 4893 Max: 6375 Ignored: 0
# ----------------------------------------------
# [ 4893, 4967)  1   0.33%   0.33%
# [ 4967, 5041)  2   0.67%   1.00%
# [ 5041, 5115)  3   1.00%   2.00% #
# [ 5115, 5189) 13   4.33%   6.33% ###
# [ 5189, 5263) 20   6.67%  13.00% ####
# [ 5263, 5337) 13   4.33%  17.33% ###
# [ 5337, 5412) 30  10.00%  27.33% ######
# [ 5412, 5486) 39  13.00%  40.33% ########
# [ 5486, 5560) 49  16.33%  56.67% ##########
# [ 5560, 5634) 36  12.00%  68.67% #######
# [ 5634, 5708) 38  12.67%  81.33% ########
# [ 5708, 5782) 18   6.00%  87.33% ####
# [ 5782, 5856) 21   7.00%  94.33% ####
# [ 5856, 5931)  8   2.67%  97.00% ##
# [ 5931, 6005)  3   1.00%  98.00% #
# [ 6005, 6079)  3   1.00%  99.00% #
# [ 6079, 6153)  0   0.00%  99.00%
# [ 6153, 6227)  1   0.33%  99.33%
# [ 6227, 6301)  1   0.33%  99.67%
# [ 6301, 6375]  1   0.33% 100.00%
#
# Depth by leafs:
# Count: 829814 Average: 13.289 StdDev: 1.94335
# Min: 3 Max: 15 Ignored: 0
# ----------------------------------------------
# [  3,  4)      3   0.00%   0.00%
# [  4,  5)     15   0.00%   0.00%
# [  5,  6)    253   0.03%   0.03%
# [  6,  7)   1400   0.17%   0.20%
# [  7,  8)   5076   0.61%   0.81%
# [  8,  9)  12854   1.55%   2.36%
# [  9, 10)  25569   3.08%   5.44% #
# [ 10, 11)  43359   5.23%  10.67% #
# [ 11, 12)  65630   7.91%  18.58% ##
# [ 12, 13)  90044  10.85%  29.43% ###
# [ 13, 14) 115772  13.95%  43.38% ####
# [ 14, 15) 139489  16.81%  60.19% ####
# [ 15, 15] 330350  39.81% 100.00% ##########
#
# Number of training obs by leaf:
# Count: 829814 Average: 114.032 StdDev: 493.713
# Min: 5 Max: 24586 Ignored: 0
# ----------------------------------------------
# [     5,  1234) 816902  98.44%  98.44% ##########
# [  1234,  2463)   7568   0.91%  99.36%
# [  2463,  3692)   2432   0.29%  99.65%
# [  3692,  4921)   1150   0.14%  99.79%
# [  4921,  6150)    617   0.07%  99.86%
# [  6150,  7379)    357   0.04%  99.91%
# [  7379,  8608)    252   0.03%  99.94%
# [  8608,  9837)    194   0.02%  99.96%
# [  9837, 11066)    122   0.01%  99.97%
# [ 11066, 12296)     65   0.01%  99.98%
# [ 12296, 13525)     53   0.01%  99.99%
# [ 13525, 14754)     27   0.00%  99.99%
# [ 14754, 15983)     25   0.00%  99.99%
# [ 15983, 17212)     15   0.00% 100.00%
# [ 17212, 18441)     18   0.00% 100.00%
# [ 18441, 19670)      8   0.00% 100.00%
# [ 19670, 20899)      7   0.00% 100.00%
# [ 20899, 22128)      1   0.00% 100.00%
# [ 22128, 23357)      0   0.00% 100.00%
# [ 23357, 24586]      1   0.00% 100.00%
#
# Attribute in nodes:
# 	62836 : Skewness [NUMERICAL]
# 	58614 : Maximum [NUMERICAL]
# 	56397 : Range [NUMERICAL]
# 	55399 : Kurtosis [NUMERICAL]
# 	49448 : Uniformity [NUMERICAL]
# 	48925 : Median [NUMERICAL]
# 	46971 : 90Percentile [NUMERICAL]
# 	46702 : Minimum [NUMERICAL]
# 	46575 : Entropy [NUMERICAL]
# 	46223 : Variance [NUMERICAL]
# 	45240 : RobustMeanAbsoluteDeviation [NUMERICAL]
# 	44061 : InterquartileRange [NUMERICAL]
# 	43322 : 10Percentile [NUMERICAL]
# 	42524 : MeanAbsoluteDeviation [NUMERICAL]
# 	38724 : Mean [NUMERICAL]
# 	32556 : Energy [NUMERICAL]
# 	32531 : RootMeanSquared [NUMERICAL]
# 	32466 : TotalEnergy [NUMERICAL]
#
# Attribute in nodes with depth <= 0:
# 	94 : Mean [NUMERICAL]
# 	64 : RootMeanSquared [NUMERICAL]
# 	47 : TotalEnergy [NUMERICAL]
# 	47 : Energy [NUMERICAL]
# 	26 : Median [NUMERICAL]
# 	11 : 90Percentile [NUMERICAL]
# 	8 : 10Percentile [NUMERICAL]
# 	2 : Minimum [NUMERICAL]
# 	1 : Maximum [NUMERICAL]
#
# Attribute in nodes with depth <= 1:
# 	240 : Mean [NUMERICAL]
# 	191 : RootMeanSquared [NUMERICAL]
# 	165 : TotalEnergy [NUMERICAL]
# 	164 : Energy [NUMERICAL]
# 	63 : Median [NUMERICAL]
# 	37 : 90Percentile [NUMERICAL]
# 	15 : Minimum [NUMERICAL]
# 	15 : 10Percentile [NUMERICAL]
# 	5 : Maximum [NUMERICAL]
# 	2 : Kurtosis [NUMERICAL]
# 	1 : Uniformity [NUMERICAL]
# 	1 : Range [NUMERICAL]
# 	1 : Entropy [NUMERICAL]
#
# Attribute in nodes with depth <= 2:
# 	351 : Mean [NUMERICAL]
# 	284 : RootMeanSquared [NUMERICAL]
# 	276 : TotalEnergy [NUMERICAL]
# 	267 : Energy [NUMERICAL]
# 	156 : 90Percentile [NUMERICAL]
# 	150 : Range [NUMERICAL]
# 	139 : Maximum [NUMERICAL]
# 	125 : Minimum [NUMERICAL]
# 	117 : Median [NUMERICAL]
# 	93 : Kurtosis [NUMERICAL]
# 	50 : InterquartileRange [NUMERICAL]
# 	43 : 10Percentile [NUMERICAL]
# 	23 : RobustMeanAbsoluteDeviation [NUMERICAL]
# 	9 : MeanAbsoluteDeviation [NUMERICAL]
# 	8 : Uniformity [NUMERICAL]
# 	6 : Variance [NUMERICAL]
# 	2 : Entropy [NUMERICAL]
# 	1 : Skewness [NUMERICAL]
#
# Attribute in nodes with depth <= 3:
# 	570 : Mean [NUMERICAL]
# 	483 : RootMeanSquared [NUMERICAL]
# 	456 : Energy [NUMERICAL]
# 	446 : TotalEnergy [NUMERICAL]
# 	415 : Minimum [NUMERICAL]
# 	354 : Range [NUMERICAL]
# 	345 : 90Percentile [NUMERICAL]
# 	283 : Maximum [NUMERICAL]
# 	281 : Kurtosis [NUMERICAL]
# 	275 : Median [NUMERICAL]
# 	159 : InterquartileRange [NUMERICAL]
# 	119 : 10Percentile [NUMERICAL]
# 	102 : RobustMeanAbsoluteDeviation [NUMERICAL]
# 	64 : Uniformity [NUMERICAL]
# 	48 : MeanAbsoluteDeviation [NUMERICAL]
# 	33 : Variance [NUMERICAL]
# 	32 : Skewness [NUMERICAL]
# 	32 : Entropy [NUMERICAL]
#
# Attribute in nodes with depth <= 5:
# 	1677 : Range [NUMERICAL]
# 	1578 : Minimum [NUMERICAL]
# 	1482 : Kurtosis [NUMERICAL]
# 	1317 : Maximum [NUMERICAL]
# 	1245 : Mean [NUMERICAL]
# 	1118 : 90Percentile [NUMERICAL]
# 	1108 : InterquartileRange [NUMERICAL]
# 	1078 : Median [NUMERICAL]
# 	1035 : Skewness [NUMERICAL]
# 	990 : RobustMeanAbsoluteDeviation [NUMERICAL]
# 	970 : RootMeanSquared [NUMERICAL]
# 	953 : Energy [NUMERICAL]
# 	936 : TotalEnergy [NUMERICAL]
# 	860 : 10Percentile [NUMERICAL]
# 	651 : Uniformity [NUMERICAL]
# 	585 : MeanAbsoluteDeviation [NUMERICAL]
# 	548 : Variance [NUMERICAL]
# 	450 : Entropy [NUMERICAL]
#
# Condition type in nodes:
# 	829514 : HigherCondition
# Condition type in nodes with depth <= 0:
# 	300 : HigherCondition
# Condition type in nodes with depth <= 1:
# 	900 : HigherCondition
# Condition type in nodes with depth <= 2:
# 	2100 : HigherCondition
# Condition type in nodes with depth <= 3:
# 	4497 : HigherCondition
# Condition type in nodes with depth <= 5:
# 	18581 : HigherCondition
# Node format: NOT_SET
#
# Training OOB:
# 	trees: 1, Out-of-bag evaluation: accuracy:0.797401 logloss:7.3024
# 	trees: 11, Out-of-bag evaluation: accuracy:0.809023 logloss:3.22101
# 	trees: 21, Out-of-bag evaluation: accuracy:0.821074 logloss:2.06803
# 	trees: 31, Out-of-bag evaluation: accuracy:0.826046 logloss:1.6634
# 	trees: 41, Out-of-bag evaluation: accuracy:0.82822 logloss:1.43959
# 	trees: 51, Out-of-bag evaluation: accuracy:0.829485 logloss:1.25972
# 	trees: 61, Out-of-bag evaluation: accuracy:0.831435 logloss:1.15439
# 	trees: 71, Out-of-bag evaluation: accuracy:0.832753 logloss:1.06392
# 	trees: 81, Out-of-bag evaluation: accuracy:0.832264 logloss:1.01691
# 	trees: 91, Out-of-bag evaluation: accuracy:0.833239 logloss:0.951314
# 	trees: 101, Out-of-bag evaluation: accuracy:0.834078 logloss:0.908143
# 	trees: 111, Out-of-bag evaluation: accuracy:0.834047 logloss:0.874203
# 	trees: 121, Out-of-bag evaluation: accuracy:0.834095 logloss:0.843007
# 	trees: 131, Out-of-bag evaluation: accuracy:0.834608 logloss:0.819714
# 	trees: 141, Out-of-bag evaluation: accuracy:0.834126 logloss:0.793773
# 	trees: 151, Out-of-bag evaluation: accuracy:0.834416 logloss:0.776502
# 	trees: 161, Out-of-bag evaluation: accuracy:0.834392 logloss:0.761674
# 	trees: 171, Out-of-bag evaluation: accuracy:0.834605 logloss:0.750356
# 	trees: 181, Out-of-bag evaluation: accuracy:0.834731 logloss:0.730161
# 	trees: 191, Out-of-bag evaluation: accuracy:0.83485 logloss:0.715495
# 	trees: 201, Out-of-bag evaluation: accuracy:0.834752 logloss:0.702185
# 	trees: 211, Out-of-bag evaluation: accuracy:0.834697 logloss:0.689193
# 	trees: 221, Out-of-bag evaluation: accuracy:0.834621 logloss:0.680445
# 	trees: 231, Out-of-bag evaluation: accuracy:0.83454 logloss:0.670852
# 	trees: 241, Out-of-bag evaluation: accuracy:0.834671 logloss:0.661739
# 	trees: 251, Out-of-bag evaluation: accuracy:0.834753 logloss:0.653624
# 	trees: 261, Out-of-bag evaluation: accuracy:0.834766 logloss:0.645004
# 	trees: 271, Out-of-bag evaluation: accuracy:0.834999 logloss:0.640795
# 	trees: 281, Out-of-bag evaluation: accuracy:0.834883 logloss:0.6315
# 	trees: 291, Out-of-bag evaluation: accuracy:0.835178 logloss:0.622748
# 	trees: 300, Out-of-bag evaluation: accuracy:0.835346 logloss:0.61788

# %%
# Model features
model.make_inspector().features()
# Out:
# ["10Percentile" (1; #0),
#  "90Percentile" (1; #1),
#  "Energy" (1; #2),
#  "Entropy" (1; #3),
#  "InterquartileRange" (1; #4),
#  "Kurtosis" (1; #5),
#  "Maximum" (1; #6),
#  "Mean" (1; #7),
#  "MeanAbsoluteDeviation" (1; #8),
#  "Median" (1; #9),
#  "Minimum" (1; #10),
#  "Range" (1; #11),
#  "RobustMeanAbsoluteDeviation" (1; #12),
#  "RootMeanSquared" (1; #13),
#  "Skewness" (1; #14),
#  "TotalEnergy" (1; #15),
#  "Uniformity" (1; #16),
#  "Variance" (1; #17)]

# %%
# Feature importance
model.make_inspector().variable_importances()
# Out:
# {'INV_MEAN_MIN_DEPTH': [("Mean" (1; #7), 0.14790321158228414),
#   ("RootMeanSquared" (1; #13), 0.1392967920745831),
#   ("Energy" (1; #2), 0.13152074205167555),
#   ("TotalEnergy" (1; #15), 0.12745765346903784),
#   ("Minimum" (1; #10), 0.11608433064791719),
#   ("90Percentile" (1; #1), 0.11459029011651232),
#   ("Maximum" (1; #6), 0.11199552011688381),
#   ("Range" (1; #11), 0.10113018498361147),
#   ("Median" (1; #9), 0.10040433587561283),
#   ("Kurtosis" (1; #5), 0.09657791867465654),
#   ("InterquartileRange" (1; #4), 0.09083914212783736),
#   ("10Percentile" (1; #0), 0.09051775294071851),
#   ("Skewness" (1; #14), 0.08949962761538724),
#   ("RobustMeanAbsoluteDeviation" (1; #12), 0.08772953918023012),
#   ("Uniformity" (1; #16), 0.08318301478508407),
#   ("MeanAbsoluteDeviation" (1; #8), 0.0817644482945128),
#   ("Variance" (1; #17), 0.08129501825457813),
#   ("Entropy" (1; #3), 0.07821783871775279)],
#  'NUM_AS_ROOT': [("Mean" (1; #7), 94.0),
#   ("RootMeanSquared" (1; #13), 64.0),
#   ("Energy" (1; #2), 47.0),
#   ("TotalEnergy" (1; #15), 47.0),
#   ("Median" (1; #9), 26.0),
#   ("90Percentile" (1; #1), 11.0),
#   ("10Percentile" (1; #0), 8.0),
#   ("Minimum" (1; #10), 2.0),
#   ("Maximum" (1; #6), 1.0)],
#  'SUM_SCORE': [("Mean" (1; #7), 5677386.803792893),
#   ("RootMeanSquared" (1; #13), 4879380.666346725),
#   ("Energy" (1; #2), 4342830.6058222335),
#   ("TotalEnergy" (1; #15), 4177057.529797265),
#   ("90Percentile" (1; #1), 3387812.43995577),
#   ("Maximum" (1; #6), 3196144.265660172),
#   ("Median" (1; #9), 2630334.6104505984),
#   ("Minimum" (1; #10), 2525553.506216061),
#   ("Range" (1; #11), 2234520.357332869),
#   ("Kurtosis" (1; #5), 1956350.6605855394),
#   ("Skewness" (1; #14), 1906273.4315400438),
#   ("10Percentile" (1; #0), 1837085.899053555),
#   ("InterquartileRange" (1; #4), 1557979.9787497693),
#   ("RobustMeanAbsoluteDeviation" (1; #12), 1491611.00801847),
#   ("Uniformity" (1; #16), 1291845.3677959477),
#   ("Variance" (1; #17), 1251419.952918958),
#   ("MeanAbsoluteDeviation" (1; #8), 1234304.159238204),
#   ("Entropy" (1; #3), 1022538.1078740633)],
#  'NUM_NODES': [("Skewness" (1; #14), 62836.0),
#   ("Maximum" (1; #6), 58614.0),
#   ("Range" (1; #11), 56397.0),
#   ("Kurtosis" (1; #5), 55399.0),
#   ("Uniformity" (1; #16), 49448.0),
#   ("Median" (1; #9), 48925.0),
#   ("90Percentile" (1; #1), 46971.0),
#   ("Minimum" (1; #10), 46702.0),
#   ("Entropy" (1; #3), 46575.0),
#   ("Variance" (1; #17), 46223.0),
#   ("RobustMeanAbsoluteDeviation" (1; #12), 45240.0),
#   ("InterquartileRange" (1; #4), 44061.0),
#   ("10Percentile" (1; #0), 43322.0),
#   ("MeanAbsoluteDeviation" (1; #8), 42524.0),
#   ("Mean" (1; #7), 38724.0),
#   ("Energy" (1; #2), 32556.0),
#   ("RootMeanSquared" (1; #13), 32531.0),
#   ("TotalEnergy" (1; #15), 32466.0)]}

# %%
# Model self evaluation
model.make_inspector().evaluation()
# Out:
# Evaluation(num_examples=315417, accuracy=0.8353456488970744, loss=0.6178798075432278, rmse=None, ndcg=None, aucs=None, auuc=None, qini=None)

# %%
logs = model.make_inspector().training_logs()

plt.figure(figsize=(12, 4))
plt.subplot(1, 2, 1)
plt.plot([log.num_trees for log in logs], [log.evaluation.accuracy for log in logs])
plt.xlabel("Number of trees")
plt.ylabel("Accuracy (out-of-bag)")
plt.subplot(1, 2, 2)
plt.plot([log.num_trees for log in logs], [log.evaluation.loss for log in logs])
plt.xlabel("Number of trees")
plt.ylabel("Logloss (out-of-bag)")
plt.show()

# %% [markdown]
# Calculate the score of our hold-out validation dataset

# %%
predictions = model.predict(val_ds)
y_true      = validation_data["label"]

from sklearn.metrics import roc_auc_score
ROC_AUC = roc_auc_score(y_true, predictions)
print("The ROC AUC score is %.5f" % ROC_AUC )
# Out:
#  1/46 [..............................] - ETA: 4s
#  3/46 [>.............................] - ETA: 1s
#  5/46 [==>...........................] - ETA: 1s
#  7/46 [===>..........................] - ETA: 1s
#  9/46 [====>.........................] - ETA: 1s
# 11/46 [======>.......................] - ETA: 1s
# 13/46 [=======>......................] - ETA: 1s
# 15/46 [========>.....................] - ETA: 1s
# 17/46 [==========>...................] - ETA: 1s
# 19/46 [===========>..................] - ETA: 0s
# 21/46 [============>.................] - ETA: 0s
# 23/46 [==============>...............] - ETA: 0s
# 25/46 [===============>..............] - ETA: 0s
# 27/46 [================>.............] - ETA: 0s
# 29/46 [=================>............] - ETA: 0s
# 31/46 [===================>..........] - ETA: 0s
# 33/46 [====================>.........] - ETA: 0s
# 35/46 [=====================>........] - ETA: 0s
# 37/46 [=======================>......] - ETA: 0s
# 39/46 [========================>.....] - ETA: 0s
# 41/46 [=========================>....] - ETA: 0s
# 43/46 [===========================>..] - ETA: 0s
# 45/46 [============================>.] - ETA: 0s
# 46/46 [==============================] - 2s 35ms/step
# The ROC AUC score is 0.92175

# %%
# Compute binary classification metrics with sklearn
import numpy as np
from sklearn.metrics import (
    accuracy_score,
    precision_score,
    recall_score,
    f1_score,
    roc_auc_score,
    average_precision_score,
    confusion_matrix,
    classification_report,
    matthews_corrcoef,
    log_loss,
    brier_score_loss,
)

# Get predictions (probabilities or class labels)
preds = model.predict(test_ds)
# If model outputs probabilities, convert to labels by threshold 0.5
if preds.ndim == 2:
    # For TFDF classification, preds may be class probabilities with shape (N, 2)
    if preds.shape[1] == 2:
        pos_probs = preds[:, 1]
    else:
        # If single-probability column (positive class)
        pos_probs = preds[:, -1]
    y_pred = (pos_probs >= 0.5).astype(int)
else:
    # Already class labels
    y_pred = preds.astype(int)
    pos_probs = None

# Ground truth labels (must be 0/1 integers)
y_true = test_data["label"].astype(int).to_numpy()

# Core metrics
metrics = {}
metrics["accuracy"] = accuracy_score(y_true, y_pred)
metrics["precision"] = precision_score(y_true, y_pred, zero_division=0)
metrics["recall"] = recall_score(y_true, y_pred, zero_division=0)
metrics["f1"] = f1_score(y_true, y_pred, zero_division=0)
metrics["mcc"] = matthews_corrcoef(y_true, y_pred)

# Probabilistic metrics (only if we have probabilities)
if pos_probs is not None:
    metrics["roc_auc"] = roc_auc_score(y_true, pos_probs)
    metrics["pr_auc"] = average_precision_score(y_true, pos_probs)
    metrics["log_loss"] = log_loss(y_true, pos_probs, labels=[0,1])
    metrics["brier_score"] = brier_score_loss(y_true, pos_probs)

# Confusion matrix and detailed report
cm = confusion_matrix(y_true, y_pred, labels=[0,1])
report = classification_report(y_true, y_pred, digits=4)

print("Sklearn binary metrics:")
for k, v in metrics.items():
    print(f"{k}: {v:.4f}")
print("\nConfusion matrix:\n", cm)
print("\nClassification report:\n", report)
# Out:
#  1/91 [..............................] - ETA: 8s
#  3/91 [..............................] - ETA: 3s
#  5/91 [>.............................] - ETA: 3s
#  7/91 [=>............................] - ETA: 2s
#  9/91 [=>............................] - ETA: 2s
# 11/91 [==>...........................] - ETA: 2s
# 13/91 [===>..........................] - ETA: 2s
# 15/91 [===>..........................] - ETA: 2s
# 17/91 [====>.........................] - ETA: 2s
# 19/91 [=====>........................] - ETA: 2s
# 21/91 [=====>........................] - ETA: 2s
# 23/91 [======>.......................] - ETA: 2s
# 25/91 [=======>......................] - ETA: 2s
# 27/91 [=======>......................] - ETA: 2s
# 29/91 [========>.....................] - ETA: 2s
# 31/91 [=========>....................] - ETA: 2s
# 33/91 [=========>....................] - ETA: 2s
# 35/91 [==========>...................] - ETA: 2s
# 37/91 [===========>..................] - ETA: 1s
# 39/91 [===========>..................] - ETA: 1s
# 41/91 [============>.................] - ETA: 1s
# 43/91 [=============>................] - ETA: 1s
# 45/91 [=============>................] - ETA: 1s
# 47/91 [==============>...............] - ETA: 1s
# 49/91 [===============>..............] - ETA: 1s
# 51/91 [===============>..............] - ETA: 1s
# 53/91 [================>.............] - ETA: 1s
# 55/91 [=================>............] - ETA: 1s
# 57/91 [=================>............] - ETA: 1s
# 59/91 [==================>...........] - ETA: 1s
# 61/91 [===================>..........] - ETA: 1s
# 63/91 [===================>..........] - ETA: 1s
# 65/91 [====================>.........] - ETA: 0s
# 67/91 [=====================>........] - ETA: 0s
# 69/91 [=====================>........] - ETA: 0s
# 71/91 [======================>.......] - ETA: 0s
# 73/91 [=======================>......] - ETA: 0s
# 75/91 [=======================>......] - ETA: 0s
# 77/91 [========================>.....] - ETA: 0s
# 79/91 [=========================>....] - ETA: 0s
# 81/91 [=========================>....] - ETA: 0s
# 83/91 [==========================>...] - ETA: 0s
# 85/91 [===========================>..] - ETA: 0s
# 87/91 [===========================>..] - ETA: 0s
# 89/91 [============================>.] - ETA: 0s
# 91/91 [==============================] - 3s 36ms/step
# Sklearn binary metrics:
# accuracy: 0.9032
# precision: 0.3667
# recall: 0.7605
# f1: 0.4948
# mcc: 0.4851
# roc_auc: 0.9246
# pr_auc: 0.5858
# log_loss: 0.2394
# brier_score: 0.0700
#
# Confusion matrix:
#  [[77124  7379]
#  [ 1345  4272]]
#
# Classification report:
#                precision    recall  f1-score   support
#
#            0     0.9829    0.9127    0.9465     84503
#            1     0.3667    0.7605    0.4948      5617
#
#     accuracy                         0.9032     90120
#    macro avg     0.6748    0.8366    0.7206     90120
# weighted avg     0.9445    0.9032    0.9183     90120
