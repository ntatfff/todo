# %%
# Import packages and modules
import numpy  as np
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow_decision_forests as tfdf

from sklearn.model_selection import train_test_split
# Out:
# 2026-07-04 08:20:30.113090: I tensorflow/core/util/port.cc:113] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2026-07-04 08:20:30.152282: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2026-07-04 08:20:34.344804: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
# Check the version of TensorFlow Decision Forests
print("Found TensorFlow Decision Forests v" + tfdf.__version__)
# Out:
# Found TensorFlow Decision Forests v1.9.1

# %%
datasetPath = 'dataset/firstorder/kernel5-radius5/dataset.csv'

# %%
# Parameters
datasetPath = "dataset/glcm/kernel5-radius5/300.dataset.csv"

# %%
# train/validation/test = 70/10/20
dataset = pd.read_csv(datasetPath)

train_data, temp_data = train_test_split(dataset, test_size=0.3, random_state=42)
validation_data, test_data = train_test_split(temp_data, test_size=2/3, random_state=42)

# %%
from sklearn.utils.class_weight import compute_class_weight

# tinh class weight tren tap train
classes = np.array([0, 1])
weights = compute_class_weight(class_weight="balanced", classes=classes, y=train_data["label"])
class_weight = {0: weights[0], 1: weights[1]}

# gan sample_weight cho tung dong
train_data["sample_weight"] = train_data["label"].map(class_weight)
validation_data["sample_weight"] = validation_data["label"].map(class_weight)
test_data["sample_weight"] = test_data["label"].map(class_weight)

# Convert the dataset into a TensorFlow dataset.
train_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    train_data, label="label", weight="sample_weight"
)         
val_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    validation_data, label="label", weight="sample_weight"
)
test_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    test_data, label="label", weight="sample_weight"
)
# Out:
# 2026-07-04 08:20:48.598041: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:984] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2026-07-04 08:20:48.599839: W tensorflow/core/common_runtime/gpu/gpu_device.cc:2251] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...

# %%
import keras

# %%
# %%time

# Train a Gradient Boosted Trees model.
model = tfdf.keras.GradientBoostedTreesModel()

# Add evaluation metrics
model.compile(
    metrics=["accuracy"]
)
model.fit(x=train_ds)

# # Train a Gradient Boosted Trees model.
# model = tfdf.keras.GradientBoostedTreesModel(num_trees=1500)
# model.fit(train_ds)
# Out:
# Use /tmp/tmp394lww9d as temporary training directory
# Reading training dataset...
# [WARNING 26-07-04 08:20:48.8554 UTC gradient_boosted_trees.cc:1840] "goss_alpha" set but "sampling_method" not equal to "GOSS".
# [WARNING 26-07-04 08:20:48.8555 UTC gradient_boosted_trees.cc:1851] "goss_beta" set but "sampling_method" not equal to "GOSS".
# [WARNING 26-07-04 08:20:48.8555 UTC gradient_boosted_trees.cc:1865] "selective_gradient_boosting_ratio" set but "sampling_method" not equal to "SELGB".
# Training dataset read in 0:00:03.913407. Found 235478 examples.
# Training model...
# Model trained in 0:00:58.931354
# Compiling model...
# [INFO 26-07-04 08:21:51.7135 UTC kernel.cc:1233] Loading model from path /tmp/tmp394lww9d/model/ with prefix 89fec0b2cd594831
# [INFO 26-07-04 08:21:51.7246 UTC quick_scorer_extended.cc:911] The binary was compiled without AVX2 support, but your CPU supports it. Enable it for faster model inference.
# [INFO 26-07-04 08:21:51.7254 UTC abstract_model.cc:1362] Engine "GradientBoostedTreesQuickScorerExtended" built
# [INFO 26-07-04 08:21:51.7254 UTC kernel.cc:1061] Use fast generic engine
# Model compiled.
# CPU times: user 9min 23s, sys: 4.35 s, total: 9min 27s
# Wall time: 1min 5s

# %%
# Evaluate the model
evaluate = model.evaluate(val_ds, return_dict=True)
print()

for name, value in evaluate.items():
    print(f"{name}: {value:.4f}")
# Out:
# WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
#  1/34 [..............................] - ETA: 1:37 - loss: 0.0000e+00 - accuracy: 0.9060
#  9/34 [======>.......................] - ETA: 0s - loss: 0.0000e+00 - accuracy: 0.9317
# 18/34 [==============>...............] - ETA: 0s - loss: 0.0000e+00 - accuracy: 0.9295
# 27/34 [======================>.......] - ETA: 0s - loss: 0.0000e+00 - accuracy: 0.9307
# 34/34 [==============================] - 3s 6ms/step - loss: 0.0000e+00 - accuracy: 0.9297
# loss: 0.0000
# accuracy: 0.9297

# %%
# Model Summary
model.summary()
# Out:
# Model: "gradient_boosted_trees_model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
# =================================================================
# Total params: 1 (1.00 Byte)
# Trainable params: 0 (0.00 Byte)
# Non-trainable params: 1 (1.00 Byte)
# _________________________________________________________________
# Type: "GRADIENT_BOOSTED_TREES"
# Task: CLASSIFICATION
# Label: "__LABEL"
#
# Input Features (24):
# 	Autocorrelation
# 	ClusterProminence
# 	ClusterShade
# 	ClusterTendency
# 	Contrast
# 	Correlation
# 	DifferenceAverage
# 	DifferenceEntropy
# 	DifferenceVariance
# 	Id
# 	Idm
# 	Idmn
# 	Idn
# 	Imc1
# 	Imc2
# 	InverseVariance
# 	JointAverage
# 	JointEnergy
# 	JointEntropy
# 	MCC
# 	MaximumProbability
# 	SumAverage
# 	SumEntropy
# 	SumSquares
#
# Trained with weights
#
# Variable Importance: INV_MEAN_MIN_DEPTH:
#     1.               "Idmn"  0.244885 ################
#     2.                "Idn"  0.237018 ##############
#     3.    "Autocorrelation"  0.203501 #######
#     4.         "SumAverage"  0.200322 ######
#     5.       "ClusterShade"  0.200104 ######
#     6.       "JointAverage"  0.200052 ######
#     7.        "Correlation"  0.194322 #####
#     8.               "Imc1"  0.193396 ####
#     9. "DifferenceVariance"  0.191305 ####
#    10.    "InverseVariance"  0.188896 ###
#    11.  "DifferenceEntropy"  0.187660 ###
#    12.           "Contrast"  0.183385 ##
#    13.  "DifferenceAverage"  0.180037 #
#    14.               "Imc2"  0.179496 #
#    15. "MaximumProbability"  0.178638 #
#    16.         "SumEntropy"  0.176075 #
#    17.                "MCC"  0.175309
#    18.  "ClusterProminence"  0.175194
#    19.         "SumSquares"  0.175034
#    20.        "JointEnergy"  0.174255
#    21.                 "Id"  0.173863
#    22.                "Idm"  0.173647
#    23.    "ClusterTendency"  0.173392
#    24.       "JointEntropy"  0.171037
#
# Variable Importance: NUM_AS_ROOT:
#     1.               "Idmn" 62.000000 ################
#     2.                "Idn" 49.000000 ############
#     3.         "SumAverage" 21.000000 #####
#     4.       "JointAverage" 19.000000 ####
#     5.               "Imc1" 18.000000 ####
#     6.    "Autocorrelation" 17.000000 ####
#     7.        "Correlation" 15.000000 ###
#     8.    "InverseVariance"  3.000000
#     9.                "MCC"  3.000000
#    10.           "Contrast"  2.000000
#    11.               "Imc2"  2.000000
#    12.       "ClusterShade"  1.000000
#    13.    "ClusterTendency"  1.000000
#    14.  "DifferenceAverage"  1.000000
#    15.  "DifferenceEntropy"  1.000000
#    16. "DifferenceVariance"  1.000000
#
# Variable Importance: NUM_NODES:
#     1.    "Autocorrelation" 620.000000 ################
#     2.                "Idn" 490.000000 ############
#     3.               "Idmn" 479.000000 ###########
#     4.       "ClusterShade" 462.000000 ###########
#     5.         "SumAverage" 377.000000 #########
#     6.       "JointAverage" 357.000000 ########
#     7.    "InverseVariance" 345.000000 ########
#     8. "DifferenceVariance" 300.000000 ######
#     9.        "Correlation" 257.000000 #####
#    10.  "DifferenceEntropy" 252.000000 #####
#    11.               "Imc1" 237.000000 #####
#    12. "MaximumProbability" 216.000000 ####
#    13.               "Imc2" 197.000000 ###
#    14.         "SumEntropy" 168.000000 ###
#    15.           "Contrast" 165.000000 ###
#    16.  "DifferenceAverage" 141.000000 ##
#    17.                "MCC" 140.000000 ##
#    18.  "ClusterProminence" 135.000000 ##
#    19.        "JointEnergy" 112.000000 #
#    20.         "SumSquares" 107.000000 #
#    21.                 "Id" 99.000000 #
#    22.    "ClusterTendency" 90.000000
#    23.                "Idm" 88.000000
#    24.       "JointEntropy" 58.000000
#
# Variable Importance: SUM_SCORE:
#     1.    "Autocorrelation" 67076.694158 ################
#     2.         "SumAverage" 44197.972806 ##########
#     3.        "Correlation" 27492.055282 ######
#     4.       "JointAverage" 20396.072233 ####
#     5. "DifferenceVariance" 12230.710634 ##
#     6.                "Idn" 11114.044273 ##
#     7.               "Imc1" 8762.279848 ##
#     8.               "Idmn" 7973.322591 #
#     9.    "InverseVariance" 7599.591305 #
#    10.       "ClusterShade" 5357.387556 #
#    11.  "DifferenceEntropy" 3346.527204
#    12. "MaximumProbability" 2381.005428
#    13.  "DifferenceAverage" 2337.147512
#    14.           "Contrast" 1701.884806
#    15.               "Imc2" 1311.724016
#    16.  "ClusterProminence" 934.388837
#    17.                 "Id" 870.413348
#    18.         "SumEntropy" 822.002856
#    19.         "SumSquares" 544.768723
#    20.                "Idm" 435.442234
#    21.        "JointEnergy" 434.246840
#    22.                "MCC" 434.150061
#    23.    "ClusterTendency" 384.698501
#    24.       "JointEntropy" 226.786182
#
#
#
# Loss: BINOMIAL_LOG_LIKELIHOOD
# Validation loss value: 0.390963
# Number of trees per iteration: 1
# Node format: NOT_SET
# Number of trees: 216
# Total number of nodes: 12000
#
# Number of nodes by tree:
# Count: 216 Average: 55.5556 StdDev: 7.67552
# Min: 33 Max: 63 Ignored: 0
# ----------------------------------------------
# [ 33, 34)  1   0.46%   0.46%
# [ 34, 36)  3   1.39%   1.85%
# [ 36, 37)  0   0.00%   1.85%
# [ 37, 39)  4   1.85%   3.70% #
# [ 39, 40)  0   0.00%   3.70%
# [ 40, 42)  8   3.70%   7.41% #
# [ 42, 43)  0   0.00%   7.41%
# [ 43, 45)  5   2.31%   9.72% #
# [ 45, 46)  7   3.24%  12.96% #
# [ 46, 48) 14   6.48%  19.44% ##
# [ 48, 50) 12   5.56%  25.00% ##
# [ 50, 51)  0   0.00%  25.00%
# [ 51, 53)  8   3.70%  28.70% #
# [ 53, 54) 11   5.09%  33.80% ##
# [ 54, 56) 23  10.65%  44.44% ###
# [ 56, 57)  0   0.00%  44.44%
# [ 57, 59) 16   7.41%  51.85% ##
# [ 59, 60) 18   8.33%  60.19% ###
# [ 60, 62) 19   8.80%  68.98% ###
# [ 62, 63] 67  31.02% 100.00% ##########
#
# Depth by leafs:
# Count: 6108 Average: 4.90914 StdDev: 0.388642
# Min: 2 Max: 5 Ignored: 0
# ----------------------------------------------
# [ 2, 3)   40   0.65%   0.65%
# [ 3, 4)   89   1.46%   2.11%
# [ 4, 5)  257   4.21%   6.32%
# [ 5, 5] 5722  93.68% 100.00% ##########
#
# Number of training obs by leaf:
# Count: 6108 Average: 7490.94 StdDev: 23006.5
# Min: 5 Max: 203971 Ignored: 0
# ----------------------------------------------
# [      5,  10203) 5219  85.45%  85.45% ##########
# [  10203,  20401)  399   6.53%  91.98% #
# [  20401,  30600)  137   2.24%  94.22%
# [  30600,  40798)   72   1.18%  95.40%
# [  40798,  50996)   50   0.82%  96.22%
# [  50996,  61195)   39   0.64%  96.86%
# [  61195,  71393)   33   0.54%  97.40%
# [  71393,  81591)   22   0.36%  97.76%
# [  81591,  91790)   18   0.29%  98.05%
# [  91790, 101988)   13   0.21%  98.26%
# [ 101988, 112186)   13   0.21%  98.48%
# [ 112186, 122385)   10   0.16%  98.64%
# [ 122385, 132583)    8   0.13%  98.77%
# [ 132583, 142781)   11   0.18%  98.95%
# [ 142781, 152980)   10   0.16%  99.12%
# [ 152980, 163178)   12   0.20%  99.31%
# [ 163178, 173376)   13   0.21%  99.53%
# [ 173376, 183575)   15   0.25%  99.77%
# [ 183575, 193773)    7   0.11%  99.89%
# [ 193773, 203971]    7   0.11% 100.00%
#
# Attribute in nodes:
# 	620 : Autocorrelation [NUMERICAL]
# 	490 : Idn [NUMERICAL]
# 	479 : Idmn [NUMERICAL]
# 	462 : ClusterShade [NUMERICAL]
# 	377 : SumAverage [NUMERICAL]
# 	357 : JointAverage [NUMERICAL]
# 	345 : InverseVariance [NUMERICAL]
# 	300 : DifferenceVariance [NUMERICAL]
# 	257 : Correlation [NUMERICAL]
# 	252 : DifferenceEntropy [NUMERICAL]
# 	237 : Imc1 [NUMERICAL]
# 	216 : MaximumProbability [NUMERICAL]
# 	197 : Imc2 [NUMERICAL]
# 	168 : SumEntropy [NUMERICAL]
# 	165 : Contrast [NUMERICAL]
# 	141 : DifferenceAverage [NUMERICAL]
# 	140 : MCC [NUMERICAL]
# 	135 : ClusterProminence [NUMERICAL]
# 	112 : JointEnergy [NUMERICAL]
# 	107 : SumSquares [NUMERICAL]
# 	99 : Id [NUMERICAL]
# 	90 : ClusterTendency [NUMERICAL]
# 	88 : Idm [NUMERICAL]
# 	58 : JointEntropy [NUMERICAL]
#
# Attribute in nodes with depth <= 0:
# 	62 : Idmn [NUMERICAL]
# 	49 : Idn [NUMERICAL]
# 	21 : SumAverage [NUMERICAL]
# 	19 : JointAverage [NUMERICAL]
# 	18 : Imc1 [NUMERICAL]
# 	17 : Autocorrelation [NUMERICAL]
# 	15 : Correlation [NUMERICAL]
# 	3 : MCC [NUMERICAL]
# 	3 : InverseVariance [NUMERICAL]
# 	2 : Imc2 [NUMERICAL]
# 	2 : Contrast [NUMERICAL]
# 	1 : DifferenceVariance [NUMERICAL]
# 	1 : DifferenceEntropy [NUMERICAL]
# 	1 : DifferenceAverage [NUMERICAL]
# 	1 : ClusterTendency [NUMERICAL]
# 	1 : ClusterShade [NUMERICAL]
#
# Attribute in nodes with depth <= 1:
# 	98 : Idmn [NUMERICAL]
# 	88 : Idn [NUMERICAL]
# 	52 : ClusterShade [NUMERICAL]
# 	46 : Correlation [NUMERICAL]
# 	39 : Imc1 [NUMERICAL]
# 	37 : DifferenceVariance [NUMERICAL]
# 	37 : DifferenceEntropy [NUMERICAL]
# 	35 : JointAverage [NUMERICAL]
# 	34 : Autocorrelation [NUMERICAL]
# 	32 : Contrast [NUMERICAL]
# 	31 : SumAverage [NUMERICAL]
# 	24 : DifferenceAverage [NUMERICAL]
# 	21 : InverseVariance [NUMERICAL]
# 	15 : Imc2 [NUMERICAL]
# 	10 : MaximumProbability [NUMERICAL]
# 	9 : SumSquares [NUMERICAL]
# 	9 : MCC [NUMERICAL]
# 	7 : SumEntropy [NUMERICAL]
# 	6 : Idm [NUMERICAL]
# 	5 : Id [NUMERICAL]
# 	5 : ClusterTendency [NUMERICAL]
# 	5 : ClusterProminence [NUMERICAL]
# 	3 : JointEnergy [NUMERICAL]
#
# Attribute in nodes with depth <= 2:
# 	156 : Idmn [NUMERICAL]
# 	139 : Idn [NUMERICAL]
# 	125 : ClusterShade [NUMERICAL]
# 	117 : Autocorrelation [NUMERICAL]
# 	97 : SumAverage [NUMERICAL]
# 	97 : JointAverage [NUMERICAL]
# 	89 : InverseVariance [NUMERICAL]
# 	89 : DifferenceVariance [NUMERICAL]
# 	78 : DifferenceEntropy [NUMERICAL]
# 	72 : Correlation [NUMERICAL]
# 	59 : Imc1 [NUMERICAL]
# 	59 : Contrast [NUMERICAL]
# 	42 : Imc2 [NUMERICAL]
# 	40 : DifferenceAverage [NUMERICAL]
# 	37 : MaximumProbability [NUMERICAL]
# 	30 : SumEntropy [NUMERICAL]
# 	25 : ClusterProminence [NUMERICAL]
# 	24 : SumSquares [NUMERICAL]
# 	24 : JointEnergy [NUMERICAL]
# 	19 : ClusterTendency [NUMERICAL]
# 	18 : Idm [NUMERICAL]
# 	17 : MCC [NUMERICAL]
# 	15 : Id [NUMERICAL]
# 	4 : JointEntropy [NUMERICAL]
#
# Attribute in nodes with depth <= 3:
# 	289 : Autocorrelation [NUMERICAL]
# 	284 : Idmn [NUMERICAL]
# 	267 : ClusterShade [NUMERICAL]
# 	241 : Idn [NUMERICAL]
# 	196 : SumAverage [NUMERICAL]
# 	183 : JointAverage [NUMERICAL]
# 	183 : InverseVariance [NUMERICAL]
# 	174 : DifferenceVariance [NUMERICAL]
# 	147 : DifferenceEntropy [NUMERICAL]
# 	120 : Correlation [NUMERICAL]
# 	118 : Imc1 [NUMERICAL]
# 	103 : Imc2 [NUMERICAL]
# 	102 : MaximumProbability [NUMERICAL]
# 	90 : Contrast [NUMERICAL]
# 	72 : DifferenceAverage [NUMERICAL]
# 	69 : SumEntropy [NUMERICAL]
# 	62 : ClusterProminence [NUMERICAL]
# 	57 : MCC [NUMERICAL]
# 	57 : JointEnergy [NUMERICAL]
# 	53 : SumSquares [NUMERICAL]
# 	51 : Id [NUMERICAL]
# 	49 : Idm [NUMERICAL]
# 	39 : ClusterTendency [NUMERICAL]
# 	25 : JointEntropy [NUMERICAL]
#
# Attribute in nodes with depth <= 5:
# 	620 : Autocorrelation [NUMERICAL]
# 	490 : Idn [NUMERICAL]
# 	479 : Idmn [NUMERICAL]
# 	462 : ClusterShade [NUMERICAL]
# 	377 : SumAverage [NUMERICAL]
# 	357 : JointAverage [NUMERICAL]
# 	345 : InverseVariance [NUMERICAL]
# 	300 : DifferenceVariance [NUMERICAL]
# 	257 : Correlation [NUMERICAL]
# 	252 : DifferenceEntropy [NUMERICAL]
# 	237 : Imc1 [NUMERICAL]
# 	216 : MaximumProbability [NUMERICAL]
# 	197 : Imc2 [NUMERICAL]
# 	168 : SumEntropy [NUMERICAL]
# 	165 : Contrast [NUMERICAL]
# 	141 : DifferenceAverage [NUMERICAL]
# 	140 : MCC [NUMERICAL]
# 	135 : ClusterProminence [NUMERICAL]
# 	112 : JointEnergy [NUMERICAL]
# 	107 : SumSquares [NUMERICAL]
# 	99 : Id [NUMERICAL]
# 	90 : ClusterTendency [NUMERICAL]
# 	88 : Idm [NUMERICAL]
# 	58 : JointEntropy [NUMERICAL]
#
# Condition type in nodes:
# 	5892 : HigherCondition
# Condition type in nodes with depth <= 0:
# 	216 : HigherCondition
# Condition type in nodes with depth <= 1:
# 	648 : HigherCondition
# Condition type in nodes with depth <= 2:
# 	1472 : HigherCondition
# Condition type in nodes with depth <= 3:
# 	3031 : HigherCondition
# Condition type in nodes with depth <= 5:
# 	5892 : HigherCondition
#
# Training logs:
# Number of iteration to final model: 216
# 	Iter:1 train-loss:1.283625 valid-loss:1.284402  train-accuracy:0.844139 valid-accuracy:0.842749
# 	Iter:2 train-loss:1.193264 valid-loss:1.193644  train-accuracy:0.849168 valid-accuracy:0.847911
# 	Iter:3 train-loss:1.114145 valid-loss:1.114622  train-accuracy:0.858724 valid-accuracy:0.857763
# 	Iter:4 train-loss:1.046827 valid-loss:1.047517  train-accuracy:0.866418 valid-accuracy:0.866619
# 	Iter:5 train-loss:0.990186 valid-loss:0.991723  train-accuracy:0.870580 valid-accuracy:0.870298
# 	Iter:6 train-loss:0.941815 valid-loss:0.944928  train-accuracy:0.871839 valid-accuracy:0.871362
# 	Iter:16 train-loss:0.646740 valid-loss:0.656659  train-accuracy:0.898511 valid-accuracy:0.896641
# 	Iter:26 train-loss:0.529293 valid-loss:0.544628  train-accuracy:0.908700 valid-accuracy:0.903787
# 	Iter:36 train-loss:0.467806 valid-loss:0.490112  train-accuracy:0.916221 valid-accuracy:0.909974
# 	Iter:46 train-loss:0.431221 valid-loss:0.459728  train-accuracy:0.921860 valid-accuracy:0.913980
# 	Iter:56 train-loss:0.407054 valid-loss:0.440331  train-accuracy:0.925387 valid-accuracy:0.916458
# 	Iter:66 train-loss:0.391463 valid-loss:0.429658  train-accuracy:0.927822 valid-accuracy:0.917441
# 	Iter:76 train-loss:0.377737 valid-loss:0.418708  train-accuracy:0.929986 valid-accuracy:0.919706
# 	Iter:86 train-loss:0.368352 valid-loss:0.412761  train-accuracy:0.931528 valid-accuracy:0.921910
# 	Iter:96 train-loss:0.360120 valid-loss:0.409338  train-accuracy:0.932850 valid-accuracy:0.920435
# 	Iter:106 train-loss:0.352550 valid-loss:0.405169  train-accuracy:0.934619 valid-accuracy:0.922251
# 	Iter:116 train-loss:0.346367 valid-loss:0.403687  train-accuracy:0.935752 valid-accuracy:0.921834
# 	Iter:126 train-loss:0.340062 valid-loss:0.401550  train-accuracy:0.936923 valid-accuracy:0.921896
# 	Iter:136 train-loss:0.335137 valid-loss:0.399242  train-accuracy:0.937363 valid-accuracy:0.922509
# 	Iter:146 train-loss:0.330950 valid-loss:0.397599  train-accuracy:0.938041 valid-accuracy:0.922733
# 	Iter:156 train-loss:0.326930 valid-loss:0.396213  train-accuracy:0.938735 valid-accuracy:0.923712
# 	Iter:166 train-loss:0.321450 valid-loss:0.394620  train-accuracy:0.940008 valid-accuracy:0.924960
# 	Iter:176 train-loss:0.316793 valid-loss:0.393235  train-accuracy:0.941143 valid-accuracy:0.925955
# 	Iter:186 train-loss:0.313443 valid-loss:0.392474  train-accuracy:0.941682 valid-accuracy:0.925381
# 	Iter:196 train-loss:0.309463 valid-loss:0.392330  train-accuracy:0.942397 valid-accuracy:0.924846
# 	Iter:206 train-loss:0.306594 valid-loss:0.391582  train-accuracy:0.943077 valid-accuracy:0.925183
# 	Iter:216 train-loss:0.302944 valid-loss:0.390963  train-accuracy:0.943694 valid-accuracy:0.924811
# 	Iter:226 train-loss:0.299614 valid-loss:0.391563  train-accuracy:0.944206 valid-accuracy:0.925424
# 	Iter:236 train-loss:0.296795 valid-loss:0.391071  train-accuracy:0.944816 valid-accuracy:0.925260
# 	Iter:246 train-loss:0.294001 valid-loss:0.391213  train-accuracy:0.945771 valid-accuracy:0.925119

# %%
# Model features
model.make_inspector().features()
# Out:
# ["Autocorrelation" (1; #0),
#  "ClusterProminence" (1; #1),
#  "ClusterShade" (1; #2),
#  "ClusterTendency" (1; #3),
#  "Contrast" (1; #4),
#  "Correlation" (1; #5),
#  "DifferenceAverage" (1; #6),
#  "DifferenceEntropy" (1; #7),
#  "DifferenceVariance" (1; #8),
#  "Id" (1; #9),
#  "Idm" (1; #10),
#  "Idmn" (1; #11),
#  "Idn" (1; #12),
#  "Imc1" (1; #13),
#  "Imc2" (1; #14),
#  "InverseVariance" (1; #15),
#  "JointAverage" (1; #16),
#  "JointEnergy" (1; #17),
#  "JointEntropy" (1; #18),
#  "MCC" (1; #19),
#  "MaximumProbability" (1; #20),
#  "SumAverage" (1; #21),
#  "SumEntropy" (1; #22),
#  "SumSquares" (1; #23)]

# %%
# Feature importance
model.make_inspector().variable_importances()
# Out:
# {'INV_MEAN_MIN_DEPTH': [("Idmn" (1; #11), 0.2448846901704112),
#   ("Idn" (1; #12), 0.23701809903884183),
#   ("Autocorrelation" (1; #0), 0.20350083093610763),
#   ("SumAverage" (1; #21), 0.20032234640208177),
#   ("ClusterShade" (1; #2), 0.20010418995940352),
#   ("JointAverage" (1; #16), 0.20005180818754942),
#   ("Correlation" (1; #5), 0.1943216861726134),
#   ("Imc1" (1; #13), 0.19339592367562514),
#   ("DifferenceVariance" (1; #8), 0.1913054572189866),
#   ("InverseVariance" (1; #15), 0.18889610279074867),
#   ("DifferenceEntropy" (1; #7), 0.1876604949309458),
#   ("Contrast" (1; #4), 0.18338503740465434),
#   ("DifferenceAverage" (1; #6), 0.18003748998950145),
#   ("Imc2" (1; #14), 0.17949601745408555),
#   ("MaximumProbability" (1; #20), 0.1786375531599956),
#   ("SumEntropy" (1; #22), 0.1760747355392294),
#   ("MCC" (1; #19), 0.17530923830688983),
#   ("ClusterProminence" (1; #1), 0.17519435818945625),
#   ("SumSquares" (1; #23), 0.17503427571872554),
#   ("JointEnergy" (1; #17), 0.1742550085396009),
#   ("Id" (1; #9), 0.17386298369452616),
#   ("Idm" (1; #10), 0.1736474637720549),
#   ("ClusterTendency" (1; #3), 0.17339187463303485),
#   ("JointEntropy" (1; #18), 0.1710368036357961)],
#  'SUM_SCORE': [("Autocorrelation" (1; #0), 67076.69415802606),
#   ("SumAverage" (1; #21), 44197.97280575584),
#   ("Correlation" (1; #5), 27492.05528161233),
#   ("JointAverage" (1; #16), 20396.07223315645),
#   ("DifferenceVariance" (1; #8), 12230.710634321671),
#   ("Idn" (1; #12), 11114.044273474017),
#   ("Imc1" (1; #13), 8762.27984804196),
#   ("Idmn" (1; #11), 7973.32259125965),
#   ("InverseVariance" (1; #15), 7599.591305496829),
#   ("ClusterShade" (1; #2), 5357.387556433748),
#   ("DifferenceEntropy" (1; #7), 3346.527203548571),
#   ("MaximumProbability" (1; #20), 2381.0054278684897),
#   ("DifferenceAverage" (1; #6), 2337.1475118590474),
#   ("Contrast" (1; #4), 1701.88480594597),
#   ("Imc2" (1; #14), 1311.7240158426787),
#   ("ClusterProminence" (1; #1), 934.3888365576936),
#   ("Id" (1; #9), 870.4133477983648),
#   ("SumEntropy" (1; #22), 822.0028563668076),
#   ("SumSquares" (1; #23), 544.7687231636481),
#   ("Idm" (1; #10), 435.44223400522645),
#   ("JointEnergy" (1; #17), 434.2468403492765),
#   ("MCC" (1; #19), 434.15006118828956),
#   ("ClusterTendency" (1; #3), 384.69850116328143),
#   ("JointEntropy" (1; #18), 226.78618150696087)],
#  'NUM_AS_ROOT': [("Idmn" (1; #11), 62.0),
#   ("Idn" (1; #12), 49.0),
#   ("SumAverage" (1; #21), 21.0),
#   ("JointAverage" (1; #16), 19.0),
#   ("Imc1" (1; #13), 18.0),
#   ("Autocorrelation" (1; #0), 17.0),
#   ("Correlation" (1; #5), 15.0),
#   ("InverseVariance" (1; #15), 3.0),
#   ("MCC" (1; #19), 3.0),
#   ("Contrast" (1; #4), 2.0),
#   ("Imc2" (1; #14), 2.0),
#   ("ClusterShade" (1; #2), 1.0),
#   ("ClusterTendency" (1; #3), 1.0),
#   ("DifferenceAverage" (1; #6), 1.0),
#   ("DifferenceEntropy" (1; #7), 1.0),
#   ("DifferenceVariance" (1; #8), 1.0)],
#  'NUM_NODES': [("Autocorrelation" (1; #0), 620.0),
#   ("Idn" (1; #12), 490.0),
#   ("Idmn" (1; #11), 479.0),
#   ("ClusterShade" (1; #2), 462.0),
#   ("SumAverage" (1; #21), 377.0),
#   ("JointAverage" (1; #16), 357.0),
#   ("InverseVariance" (1; #15), 345.0),
#   ("DifferenceVariance" (1; #8), 300.0),
#   ("Correlation" (1; #5), 257.0),
#   ("DifferenceEntropy" (1; #7), 252.0),
#   ("Imc1" (1; #13), 237.0),
#   ("MaximumProbability" (1; #20), 216.0),
#   ("Imc2" (1; #14), 197.0),
#   ("SumEntropy" (1; #22), 168.0),
#   ("Contrast" (1; #4), 165.0),
#   ("DifferenceAverage" (1; #6), 141.0),
#   ("MCC" (1; #19), 140.0),
#   ("ClusterProminence" (1; #1), 135.0),
#   ("JointEnergy" (1; #17), 112.0),
#   ("SumSquares" (1; #23), 107.0),
#   ("Id" (1; #9), 99.0),
#   ("ClusterTendency" (1; #3), 90.0),
#   ("Idm" (1; #10), 88.0),
#   ("JointEntropy" (1; #18), 58.0)]}

# %%
# Model self evaluation
model.make_inspector().evaluation()
# Out:
# Evaluation(num_examples=None, accuracy=0.9248108267784119, loss=0.3909625709056854, rmse=None, ndcg=None, aucs=None, auuc=None, qini=None)

# %%
logs = model.make_inspector().training_logs()

plt.figure(figsize=(12, 4))
plt.subplot(1, 2, 1)
plt.plot([log.num_trees for log in logs], [log.evaluation.accuracy for log in logs])
plt.xlabel("Number of trees")
plt.ylabel("Accuracy (out-of-bag)")
plt.subplot(1, 2, 2)
plt.plot([log.num_trees for log in logs], [log.evaluation.loss for log in logs])
plt.xlabel("Number of trees")
plt.ylabel("Logloss (out-of-bag)")
plt.show()

# %% [markdown]
# Calculate the score of our hold-out validation dataset

# %%
predictions = model.predict(val_ds)
y_true      = validation_data["label"]

from sklearn.metrics import roc_auc_score
ROC_AUC = roc_auc_score(y_true, predictions)
print("The ROC AUC score is %.5f" % ROC_AUC )
# Out:
#  1/34 [..............................] - ETA: 2s
# 10/34 [=======>......................] - ETA: 0s
# 20/34 [================>.............] - ETA: 0s
# 29/34 [========================>.....] - ETA: 0s
# 34/34 [==============================] - 0s 6ms/step
# The ROC AUC score is 0.97683

# %%
# Compute binary classification metrics with sklearn
import numpy as np
from sklearn.metrics import (
    accuracy_score,
    precision_score,
    recall_score,
    f1_score,
    roc_auc_score,
    average_precision_score,
    confusion_matrix,
    classification_report,
    matthews_corrcoef,
    log_loss,
    brier_score_loss,
)

# Get predictions (probabilities or class labels)
preds = model.predict(test_ds)
# If model outputs probabilities, convert to labels by threshold 0.5
if preds.ndim == 2:
    # For TFDF classification, preds may be class probabilities with shape (N, 2)
    if preds.shape[1] == 2:
        pos_probs = preds[:, 1]
    else:
        # If single-probability column (positive class)
        pos_probs = preds[:, -1]
    y_pred = (pos_probs >= 0.5).astype(int)
else:
    # Already class labels
    y_pred = preds.astype(int)
    pos_probs = None

# Ground truth labels (must be 0/1 integers)
y_true = test_data["label"].astype(int).to_numpy()

# Core metrics
metrics = {}
metrics["accuracy"] = accuracy_score(y_true, y_pred)
metrics["precision"] = precision_score(y_true, y_pred, zero_division=0)
metrics["recall"] = recall_score(y_true, y_pred, zero_division=0)
metrics["f1"] = f1_score(y_true, y_pred, zero_division=0)
metrics["mcc"] = matthews_corrcoef(y_true, y_pred)

# Probabilistic metrics (only if we have probabilities)
if pos_probs is not None:
    metrics["roc_auc"] = roc_auc_score(y_true, pos_probs)
    metrics["pr_auc"] = average_precision_score(y_true, pos_probs)
    metrics["log_loss"] = log_loss(y_true, pos_probs, labels=[0,1])
    metrics["brier_score"] = brier_score_loss(y_true, pos_probs)

# Confusion matrix and detailed report
cm = confusion_matrix(y_true, y_pred, labels=[0,1])
report = classification_report(y_true, y_pred, digits=4)

print("Sklearn binary metrics:")
for k, v in metrics.items():
    print(f"{k}: {v:.4f}")
print("\nConfusion matrix:\n", cm)
print("\nClassification report:\n", report)
# Out:
#  1/68 [..............................] - ETA: 5s
# 10/68 [===>..........................] - ETA: 0s
# 19/68 [=======>......................] - ETA: 0s
# 28/68 [===========>..................] - ETA: 0s
# 37/68 [===============>..............] - ETA: 0s
# 46/68 [===================>..........] - ETA: 0s
# 55/68 [=======================>......] - ETA: 0s
# 64/68 [===========================>..] - ETA: 0s
# 68/68 [==============================] - 0s 6ms/step
# Sklearn binary metrics:
# accuracy: 0.9279
# precision: 0.4522
# recall: 0.9202
# f1: 0.6064
# mcc: 0.6157
# roc_auc: 0.9766
# pr_auc: 0.8026
# log_loss: 0.1784
# brier_score: 0.0531
#
# Confusion matrix:
#  [[58696  4525]
#  [  324  3735]]
#
# Classification report:
#                precision    recall  f1-score   support
#
#            0     0.9945    0.9284    0.9603     63221
#            1     0.4522    0.9202    0.6064      4059
#
#     accuracy                         0.9279     67280
#    macro avg     0.7233    0.9243    0.7834     67280
# weighted avg     0.9618    0.9279    0.9390     67280
