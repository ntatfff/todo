# %%
# Import packages and modules
import numpy  as np
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow_decision_forests as tfdf

from sklearn.model_selection import train_test_split
# Out:
# 2026-07-04 08:19:08.053831: I tensorflow/core/util/port.cc:113] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2026-07-04 08:19:08.096226: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2026-07-04 08:19:12.380401: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
# Check the version of TensorFlow Decision Forests
print("Found TensorFlow Decision Forests v" + tfdf.__version__)
# Out:
# Found TensorFlow Decision Forests v1.9.1

# %%
datasetPath = 'dataset/firstorder/kernel5-radius5/dataset.csv'

# %%
# Parameters
datasetPath = "dataset/glcm/kernel5-radius5/200.dataset.csv"

# %%
# train/validation/test = 70/10/20
dataset = pd.read_csv(datasetPath)

train_data, temp_data = train_test_split(dataset, test_size=0.3, random_state=42)
validation_data, test_data = train_test_split(temp_data, test_size=2/3, random_state=42)

# %%
from sklearn.utils.class_weight import compute_class_weight

# tinh class weight tren tap train
classes = np.array([0, 1])
weights = compute_class_weight(class_weight="balanced", classes=classes, y=train_data["label"])
class_weight = {0: weights[0], 1: weights[1]}

# gan sample_weight cho tung dong
train_data["sample_weight"] = train_data["label"].map(class_weight)
validation_data["sample_weight"] = validation_data["label"].map(class_weight)
test_data["sample_weight"] = test_data["label"].map(class_weight)

# Convert the dataset into a TensorFlow dataset.
train_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    train_data, label="label", weight="sample_weight"
)         
val_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    validation_data, label="label", weight="sample_weight"
)
test_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    test_data, label="label", weight="sample_weight"
)
# Out:
# 2026-07-04 08:19:24.906419: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:984] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2026-07-04 08:19:24.907966: W tensorflow/core/common_runtime/gpu/gpu_device.cc:2251] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...

# %%
import keras

# %%
# %%time

# Train a Gradient Boosted Trees model.
model = tfdf.keras.GradientBoostedTreesModel()

# Add evaluation metrics
model.compile(
    metrics=["accuracy"]
)
model.fit(x=train_ds)

# # Train a Gradient Boosted Trees model.
# model = tfdf.keras.GradientBoostedTreesModel(num_trees=1500)
# model.fit(train_ds)
# Out:
# Use /tmp/tmpnjo8vgtl as temporary training directory
# Reading training dataset...
# [WARNING 26-07-04 08:19:25.0791 UTC gradient_boosted_trees.cc:1840] "goss_alpha" set but "sampling_method" not equal to "GOSS".
# [WARNING 26-07-04 08:19:25.0792 UTC gradient_boosted_trees.cc:1851] "goss_beta" set but "sampling_method" not equal to "GOSS".
# [WARNING 26-07-04 08:19:25.0792 UTC gradient_boosted_trees.cc:1865] "selective_gradient_boosting_ratio" set but "sampling_method" not equal to "SELGB".
# Training dataset read in 0:00:03.394728. Found 157360 examples.
# Training model...
# Model trained in 0:00:47.769834
# Compiling model...
# [INFO 26-07-04 08:20:16.2536 UTC kernel.cc:1233] Loading model from path /tmp/tmpnjo8vgtl/model/ with prefix bb831536c74147c5
# [INFO 26-07-04 08:20:16.2666 UTC quick_scorer_extended.cc:911] The binary was compiled without AVX2 support, but your CPU supports it. Enable it for faster model inference.
# [INFO 26-07-04 08:20:16.2675 UTC abstract_model.cc:1362] Engine "GradientBoostedTreesQuickScorerExtended" built
# [INFO 26-07-04 08:20:16.2675 UTC kernel.cc:1061] Use fast generic engine
# Model compiled.
# CPU times: user 7min 8s, sys: 4.57 s, total: 7min 12s
# Wall time: 54.3 s

# %%
# Evaluate the model
evaluate = model.evaluate(val_ds, return_dict=True)
print()

for name, value in evaluate.items():
    print(f"{name}: {value:.4f}")
# Out:
# WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
#  1/23 [>.............................] - ETA: 1:04 - loss: 0.0000e+00 - accuracy: 0.9250
# 10/23 [============>.................] - ETA: 0s - loss: 0.0000e+00 - accuracy: 0.9349
# 19/23 [=======================>......] - ETA: 0s - loss: 0.0000e+00 - accuracy: 0.9357
# 23/23 [==============================] - 3s 6ms/step - loss: 0.0000e+00 - accuracy: 0.9363
# loss: 0.0000
# accuracy: 0.9363

# %%
# Model Summary
model.summary()
# Out:
# Model: "gradient_boosted_trees_model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
# =================================================================
# Total params: 1 (1.00 Byte)
# Trainable params: 0 (0.00 Byte)
# Non-trainable params: 1 (1.00 Byte)
# _________________________________________________________________
# Type: "GRADIENT_BOOSTED_TREES"
# Task: CLASSIFICATION
# Label: "__LABEL"
#
# Input Features (24):
# 	Autocorrelation
# 	ClusterProminence
# 	ClusterShade
# 	ClusterTendency
# 	Contrast
# 	Correlation
# 	DifferenceAverage
# 	DifferenceEntropy
# 	DifferenceVariance
# 	Id
# 	Idm
# 	Idmn
# 	Idn
# 	Imc1
# 	Imc2
# 	InverseVariance
# 	JointAverage
# 	JointEnergy
# 	JointEntropy
# 	MCC
# 	MaximumProbability
# 	SumAverage
# 	SumEntropy
# 	SumSquares
#
# Trained with weights
#
# Variable Importance: INV_MEAN_MIN_DEPTH:
#     1.                "Idn"  0.240899 ################
#     2.               "Idmn"  0.231355 #############
#     3.    "Autocorrelation"  0.206882 #######
#     4.       "ClusterShade"  0.202510 ######
#     5.         "SumAverage"  0.197902 #####
#     6.       "JointAverage"  0.197570 #####
#     7. "DifferenceVariance"  0.194302 ####
#     8.        "Correlation"  0.194057 ####
#     9.               "Imc1"  0.193639 ####
#    10.    "InverseVariance"  0.192480 ####
#    11.  "DifferenceEntropy"  0.184058 ##
#    12.               "Imc2"  0.182007 #
#    13.           "Contrast"  0.181392 #
#    14.  "DifferenceAverage"  0.180568 #
#    15. "MaximumProbability"  0.179372 #
#    16.                "MCC"  0.178353 #
#    17.    "ClusterTendency"  0.177156
#    18.         "SumEntropy"  0.177142
#    19.  "ClusterProminence"  0.175416
#    20.                 "Id"  0.175214
#    21.       "JointEntropy"  0.174459
#    22.        "JointEnergy"  0.174453
#    23.         "SumSquares"  0.174001
#    24.                "Idm"  0.173683
#
# Variable Importance: NUM_AS_ROOT:
#     1.                "Idn" 69.000000 ################
#     2.               "Idmn" 57.000000 #############
#     3.    "Autocorrelation" 25.000000 #####
#     4.        "Correlation" 23.000000 #####
#     5.               "Imc1" 21.000000 ####
#     6.         "SumAverage" 21.000000 ####
#     7.       "JointAverage" 20.000000 ####
#     8.    "InverseVariance"  8.000000 #
#     9.                "MCC"  7.000000 #
#    10. "DifferenceVariance"  5.000000
#    11.               "Imc2"  4.000000
#    12.       "ClusterShade"  3.000000
#    13.           "Contrast"  3.000000
#    14.  "DifferenceEntropy"  1.000000
#
# Variable Importance: NUM_NODES:
#     1.    "Autocorrelation" 716.000000 ################
#     2.       "ClusterShade" 575.000000 ############
#     3.               "Idmn" 569.000000 ############
#     4.                "Idn" 543.000000 ###########
#     5.         "SumAverage" 412.000000 ########
#     6.       "JointAverage" 400.000000 #######
#     7.    "InverseVariance" 399.000000 #######
#     8. "DifferenceVariance" 355.000000 ######
#     9.        "Correlation" 316.000000 #####
#    10.               "Imc1" 283.000000 ####
#    11.               "Imc2" 277.000000 ####
#    12.  "DifferenceEntropy" 235.000000 ###
#    13.         "SumEntropy" 227.000000 ###
#    14. "MaximumProbability" 225.000000 ###
#    15.           "Contrast" 205.000000 ##
#    16.  "ClusterProminence" 188.000000 ##
#    17.  "DifferenceAverage" 180.000000 ##
#    18.                 "Id" 144.000000 #
#    19.        "JointEnergy" 144.000000 #
#    20.                "MCC" 137.000000
#    21.    "ClusterTendency" 134.000000
#    22.         "SumSquares" 123.000000
#    23.                "Idm" 107.000000
#    24.       "JointEntropy" 102.000000
#
# Variable Importance: SUM_SCORE:
#     1.         "SumAverage" 32796.164315 ################
#     2.    "Autocorrelation" 25173.931422 ############
#     3.        "Correlation" 24538.004191 ###########
#     4.       "JointAverage" 12478.332185 #####
#     5. "DifferenceVariance" 10256.720026 ####
#     6.    "InverseVariance" 8837.410378 ####
#     7.                "Idn" 7990.882940 ###
#     8.               "Imc1" 7615.105371 ###
#     9.               "Idmn" 6646.191942 ###
#    10.           "Contrast" 3986.435038 #
#    11.       "ClusterShade" 3701.262337 #
#    12. "MaximumProbability" 3168.348614 #
#    13.  "DifferenceEntropy" 1818.185752
#    14.  "DifferenceAverage" 1209.082740
#    15.         "SumEntropy" 929.414773
#    16.                 "Id" 865.266169
#    17.               "Imc2" 684.159567
#    18.  "ClusterProminence" 593.948852
#    19.        "JointEnergy" 541.344307
#    20.                "Idm" 484.245261
#    21.    "ClusterTendency" 446.193384
#    22.         "SumSquares" 373.101349
#    23.       "JointEntropy" 358.138501
#    24.                "MCC" 298.312074
#
#
#
# Loss: BINOMIAL_LOG_LIKELIHOOD
# Validation loss value: 0.42465
# Number of trees per iteration: 1
# Node format: NOT_SET
# Number of trees: 267
# Total number of nodes: 14259
#
# Number of nodes by tree:
# Count: 267 Average: 53.4045 StdDev: 7.95594
# Min: 31 Max: 63 Ignored: 0
# ----------------------------------------------
# [ 31, 32)  1   0.37%   0.37%
# [ 32, 34)  3   1.12%   1.50% #
# [ 34, 35)  0   0.00%   1.50%
# [ 35, 37)  3   1.12%   2.62% #
# [ 37, 39)  3   1.12%   3.75% #
# [ 39, 40)  3   1.12%   4.87% #
# [ 40, 42) 13   4.87%   9.74% ###
# [ 42, 44) 10   3.75%  13.48% ##
# [ 44, 45)  0   0.00%  13.48%
# [ 45, 47) 19   7.12%  20.60% ####
# [ 47, 49) 22   8.24%  28.84% #####
# [ 49, 50) 17   6.37%  35.21% ####
# [ 50, 52) 10   3.75%  38.95% ##
# [ 52, 54) 22   8.24%  47.19% #####
# [ 54, 55)  0   0.00%  47.19%
# [ 55, 57) 22   8.24%  55.43% #####
# [ 57, 59) 18   6.74%  62.17% ####
# [ 59, 60) 27  10.11%  72.28% ######
# [ 60, 62) 28  10.49%  82.77% ######
# [ 62, 63] 46  17.23% 100.00% ##########
#
# Depth by leafs:
# Count: 7263 Average: 4.87884 StdDev: 0.4461
# Min: 2 Max: 5 Ignored: 0
# ----------------------------------------------
# [ 2, 3)   65   0.89%   0.89%
# [ 3, 4)  141   1.94%   2.84%
# [ 4, 5)  403   5.55%   8.38% #
# [ 5, 5] 6654  91.62% 100.00% ##########
#
# Number of training obs by leaf:
# Count: 7263 Average: 5207.88 StdDev: 15797.7
# Min: 5 Max: 139308 Ignored: 0
# ----------------------------------------------
# [      5,   6970) 6174  85.01%  85.01% ##########
# [   6970,  13935)  422   5.81%  90.82% #
# [  13935,  20900)  229   3.15%  93.97%
# [  20900,  27865)   84   1.16%  95.13%
# [  27865,  34831)   76   1.05%  96.17%
# [  34831,  41796)   38   0.52%  96.70%
# [  41796,  48761)   33   0.45%  97.15%
# [  48761,  55726)   24   0.33%  97.48%
# [  55726,  62691)   30   0.41%  97.89%
# [  62691,  69657)   20   0.28%  98.17%
# [  69657,  76622)   16   0.22%  98.39%
# [  76622,  83587)   17   0.23%  98.62%
# [  83587,  90552)   18   0.25%  98.87%
# [  90552,  97517)   16   0.22%  99.09%
# [  97517, 104483)   16   0.22%  99.31%
# [ 104483, 111448)    9   0.12%  99.44%
# [ 111448, 118413)    7   0.10%  99.53%
# [ 118413, 125378)   14   0.19%  99.72%
# [ 125378, 132343)   13   0.18%  99.90%
# [ 132343, 139308]    7   0.10% 100.00%
#
# Attribute in nodes:
# 	716 : Autocorrelation [NUMERICAL]
# 	575 : ClusterShade [NUMERICAL]
# 	569 : Idmn [NUMERICAL]
# 	543 : Idn [NUMERICAL]
# 	412 : SumAverage [NUMERICAL]
# 	400 : JointAverage [NUMERICAL]
# 	399 : InverseVariance [NUMERICAL]
# 	355 : DifferenceVariance [NUMERICAL]
# 	316 : Correlation [NUMERICAL]
# 	283 : Imc1 [NUMERICAL]
# 	277 : Imc2 [NUMERICAL]
# 	235 : DifferenceEntropy [NUMERICAL]
# 	227 : SumEntropy [NUMERICAL]
# 	225 : MaximumProbability [NUMERICAL]
# 	205 : Contrast [NUMERICAL]
# 	188 : ClusterProminence [NUMERICAL]
# 	180 : DifferenceAverage [NUMERICAL]
# 	144 : JointEnergy [NUMERICAL]
# 	144 : Id [NUMERICAL]
# 	137 : MCC [NUMERICAL]
# 	134 : ClusterTendency [NUMERICAL]
# 	123 : SumSquares [NUMERICAL]
# 	107 : Idm [NUMERICAL]
# 	102 : JointEntropy [NUMERICAL]
#
# Attribute in nodes with depth <= 0:
# 	69 : Idn [NUMERICAL]
# 	57 : Idmn [NUMERICAL]
# 	25 : Autocorrelation [NUMERICAL]
# 	23 : Correlation [NUMERICAL]
# 	21 : SumAverage [NUMERICAL]
# 	21 : Imc1 [NUMERICAL]
# 	20 : JointAverage [NUMERICAL]
# 	8 : InverseVariance [NUMERICAL]
# 	7 : MCC [NUMERICAL]
# 	5 : DifferenceVariance [NUMERICAL]
# 	4 : Imc2 [NUMERICAL]
# 	3 : Contrast [NUMERICAL]
# 	3 : ClusterShade [NUMERICAL]
# 	1 : DifferenceEntropy [NUMERICAL]
#
# Attribute in nodes with depth <= 1:
# 	116 : Idn [NUMERICAL]
# 	111 : Idmn [NUMERICAL]
# 	72 : ClusterShade [NUMERICAL]
# 	52 : DifferenceVariance [NUMERICAL]
# 	50 : Autocorrelation [NUMERICAL]
# 	46 : Correlation [NUMERICAL]
# 	42 : SumAverage [NUMERICAL]
# 	42 : Imc1 [NUMERICAL]
# 	40 : InverseVariance [NUMERICAL]
# 	39 : JointAverage [NUMERICAL]
# 	38 : DifferenceEntropy [NUMERICAL]
# 	26 : DifferenceAverage [NUMERICAL]
# 	24 : Imc2 [NUMERICAL]
# 	23 : Contrast [NUMERICAL]
# 	19 : ClusterTendency [NUMERICAL]
# 	15 : MaximumProbability [NUMERICAL]
# 	15 : MCC [NUMERICAL]
# 	10 : Id [NUMERICAL]
# 	5 : SumEntropy [NUMERICAL]
# 	5 : JointEntropy [NUMERICAL]
# 	4 : JointEnergy [NUMERICAL]
# 	3 : SumSquares [NUMERICAL]
# 	2 : Idm [NUMERICAL]
# 	2 : ClusterProminence [NUMERICAL]
#
# Attribute in nodes with depth <= 2:
# 	192 : Idn [NUMERICAL]
# 	177 : Idmn [NUMERICAL]
# 	167 : ClusterShade [NUMERICAL]
# 	155 : Autocorrelation [NUMERICAL]
# 	116 : DifferenceVariance [NUMERICAL]
# 	112 : InverseVariance [NUMERICAL]
# 	111 : SumAverage [NUMERICAL]
# 	111 : JointAverage [NUMERICAL]
# 	71 : Imc1 [NUMERICAL]
# 	71 : Correlation [NUMERICAL]
# 	68 : DifferenceEntropy [NUMERICAL]
# 	59 : DifferenceAverage [NUMERICAL]
# 	53 : Imc2 [NUMERICAL]
# 	50 : Contrast [NUMERICAL]
# 	49 : MaximumProbability [NUMERICAL]
# 	42 : SumEntropy [NUMERICAL]
# 	36 : ClusterTendency [NUMERICAL]
# 	30 : MCC [NUMERICAL]
# 	28 : ClusterProminence [NUMERICAL]
# 	26 : Id [NUMERICAL]
# 	25 : JointEntropy [NUMERICAL]
# 	23 : JointEnergy [NUMERICAL]
# 	16 : SumSquares [NUMERICAL]
# 	16 : Idm [NUMERICAL]
#
# Attribute in nodes with depth <= 3:
# 	359 : Autocorrelation [NUMERICAL]
# 	329 : Idmn [NUMERICAL]
# 	305 : Idn [NUMERICAL]
# 	305 : ClusterShade [NUMERICAL]
# 	223 : InverseVariance [NUMERICAL]
# 	218 : SumAverage [NUMERICAL]
# 	206 : JointAverage [NUMERICAL]
# 	200 : DifferenceVariance [NUMERICAL]
# 	162 : Correlation [NUMERICAL]
# 	150 : Imc1 [NUMERICAL]
# 	143 : Imc2 [NUMERICAL]
# 	117 : DifferenceEntropy [NUMERICAL]
# 	115 : MaximumProbability [NUMERICAL]
# 	110 : DifferenceAverage [NUMERICAL]
# 	109 : Contrast [NUMERICAL]
# 	104 : SumEntropy [NUMERICAL]
# 	82 : ClusterProminence [NUMERICAL]
# 	71 : Id [NUMERICAL]
# 	66 : MCC [NUMERICAL]
# 	65 : JointEnergy [NUMERICAL]
# 	65 : ClusterTendency [NUMERICAL]
# 	58 : JointEntropy [NUMERICAL]
# 	55 : SumSquares [NUMERICAL]
# 	52 : Idm [NUMERICAL]
#
# Attribute in nodes with depth <= 5:
# 	716 : Autocorrelation [NUMERICAL]
# 	575 : ClusterShade [NUMERICAL]
# 	569 : Idmn [NUMERICAL]
# 	543 : Idn [NUMERICAL]
# 	412 : SumAverage [NUMERICAL]
# 	400 : JointAverage [NUMERICAL]
# 	399 : InverseVariance [NUMERICAL]
# 	355 : DifferenceVariance [NUMERICAL]
# 	316 : Correlation [NUMERICAL]
# 	283 : Imc1 [NUMERICAL]
# 	277 : Imc2 [NUMERICAL]
# 	235 : DifferenceEntropy [NUMERICAL]
# 	227 : SumEntropy [NUMERICAL]
# 	225 : MaximumProbability [NUMERICAL]
# 	205 : Contrast [NUMERICAL]
# 	188 : ClusterProminence [NUMERICAL]
# 	180 : DifferenceAverage [NUMERICAL]
# 	144 : JointEnergy [NUMERICAL]
# 	144 : Id [NUMERICAL]
# 	137 : MCC [NUMERICAL]
# 	134 : ClusterTendency [NUMERICAL]
# 	123 : SumSquares [NUMERICAL]
# 	107 : Idm [NUMERICAL]
# 	102 : JointEntropy [NUMERICAL]
#
# Condition type in nodes:
# 	6996 : HigherCondition
# Condition type in nodes with depth <= 0:
# 	267 : HigherCondition
# Condition type in nodes with depth <= 1:
# 	801 : HigherCondition
# Condition type in nodes with depth <= 2:
# 	1804 : HigherCondition
# Condition type in nodes with depth <= 3:
# 	3669 : HigherCondition
# Condition type in nodes with depth <= 5:
# 	6996 : HigherCondition
#
# Training logs:
# Number of iteration to final model: 267
# 	Iter:1 train-loss:1.282956 valid-loss:1.287014  train-accuracy:0.844951 valid-accuracy:0.831133
# 	Iter:2 train-loss:1.196814 valid-loss:1.204752  train-accuracy:0.851960 valid-accuracy:0.836888
# 	Iter:3 train-loss:1.129876 valid-loss:1.139402  train-accuracy:0.846618 valid-accuracy:0.832266
# 	Iter:4 train-loss:1.066168 valid-loss:1.078267  train-accuracy:0.855338 valid-accuracy:0.841356
# 	Iter:5 train-loss:1.010056 valid-loss:1.025568  train-accuracy:0.857232 valid-accuracy:0.840176
# 	Iter:6 train-loss:0.962649 valid-loss:0.980771  train-accuracy:0.865130 valid-accuracy:0.850621
# 	Iter:16 train-loss:0.691906 valid-loss:0.719805  train-accuracy:0.887813 valid-accuracy:0.869787
# 	Iter:26 train-loss:0.556993 valid-loss:0.595250  train-accuracy:0.906058 valid-accuracy:0.890771
# 	Iter:36 train-loss:0.486434 valid-loss:0.533813  train-accuracy:0.915736 valid-accuracy:0.901828
# 	Iter:46 train-loss:0.445004 valid-loss:0.502261  train-accuracy:0.922743 valid-accuracy:0.907098
# 	Iter:56 train-loss:0.414453 valid-loss:0.478011  train-accuracy:0.926140 valid-accuracy:0.909292
# 	Iter:66 train-loss:0.392937 valid-loss:0.462905  train-accuracy:0.930640 valid-accuracy:0.911033
# 	Iter:76 train-loss:0.378648 valid-loss:0.455611  train-accuracy:0.932572 valid-accuracy:0.911625
# 	Iter:86 train-loss:0.365626 valid-loss:0.448487  train-accuracy:0.934713 valid-accuracy:0.913451
# 	Iter:96 train-loss:0.356281 valid-loss:0.444329  train-accuracy:0.935870 valid-accuracy:0.915258
# 	Iter:106 train-loss:0.347050 valid-loss:0.441045  train-accuracy:0.937473 valid-accuracy:0.915277
# 	Iter:116 train-loss:0.338941 valid-loss:0.438083  train-accuracy:0.938858 valid-accuracy:0.915800
# 	Iter:126 train-loss:0.332009 valid-loss:0.436181  train-accuracy:0.939811 valid-accuracy:0.917293
# 	Iter:136 train-loss:0.324854 valid-loss:0.433962  train-accuracy:0.941710 valid-accuracy:0.916845
# 	Iter:146 train-loss:0.319625 valid-loss:0.433340  train-accuracy:0.942559 valid-accuracy:0.916257
# 	Iter:156 train-loss:0.313717 valid-loss:0.430514  train-accuracy:0.943647 valid-accuracy:0.916207
# 	Iter:166 train-loss:0.308841 valid-loss:0.428343  train-accuracy:0.944376 valid-accuracy:0.916884
# 	Iter:176 train-loss:0.303849 valid-loss:0.427011  train-accuracy:0.945214 valid-accuracy:0.917665
# 	Iter:186 train-loss:0.299589 valid-loss:0.427036  train-accuracy:0.946556 valid-accuracy:0.918013
# 	Iter:196 train-loss:0.294643 valid-loss:0.426259  train-accuracy:0.947718 valid-accuracy:0.918172
# 	Iter:206 train-loss:0.290543 valid-loss:0.426364  train-accuracy:0.948137 valid-accuracy:0.917809
# 	Iter:216 train-loss:0.286672 valid-loss:0.425214  train-accuracy:0.949597 valid-accuracy:0.918799
# 	Iter:226 train-loss:0.283365 valid-loss:0.424963  train-accuracy:0.950177 valid-accuracy:0.919616
# 	Iter:236 train-loss:0.279677 valid-loss:0.425211  train-accuracy:0.951262 valid-accuracy:0.918854
# 	Iter:246 train-loss:0.276020 valid-loss:0.424697  train-accuracy:0.952034 valid-accuracy:0.919063
# 	Iter:256 train-loss:0.273307 valid-loss:0.425025  train-accuracy:0.952775 valid-accuracy:0.918664
# 	Iter:266 train-loss:0.270306 valid-loss:0.424815  train-accuracy:0.953828 valid-accuracy:0.919082
# 	Iter:276 train-loss:0.267509 valid-loss:0.425245  train-accuracy:0.954203 valid-accuracy:0.918928
# 	Iter:286 train-loss:0.264415 valid-loss:0.424972  train-accuracy:0.954972 valid-accuracy:0.920003
# 	Iter:296 train-loss:0.261516 valid-loss:0.425162  train-accuracy:0.955930 valid-accuracy:0.919570

# %%
# Model features
model.make_inspector().features()
# Out:
# ["Autocorrelation" (1; #0),
#  "ClusterProminence" (1; #1),
#  "ClusterShade" (1; #2),
#  "ClusterTendency" (1; #3),
#  "Contrast" (1; #4),
#  "Correlation" (1; #5),
#  "DifferenceAverage" (1; #6),
#  "DifferenceEntropy" (1; #7),
#  "DifferenceVariance" (1; #8),
#  "Id" (1; #9),
#  "Idm" (1; #10),
#  "Idmn" (1; #11),
#  "Idn" (1; #12),
#  "Imc1" (1; #13),
#  "Imc2" (1; #14),
#  "InverseVariance" (1; #15),
#  "JointAverage" (1; #16),
#  "JointEnergy" (1; #17),
#  "JointEntropy" (1; #18),
#  "MCC" (1; #19),
#  "MaximumProbability" (1; #20),
#  "SumAverage" (1; #21),
#  "SumEntropy" (1; #22),
#  "SumSquares" (1; #23)]

# %%
# Feature importance
model.make_inspector().variable_importances()
# Out:
# {'INV_MEAN_MIN_DEPTH': [("Idn" (1; #12), 0.2408991492765943),
#   ("Idmn" (1; #11), 0.2313552005012124),
#   ("Autocorrelation" (1; #0), 0.20688171254240204),
#   ("ClusterShade" (1; #2), 0.20250956736109754),
#   ("SumAverage" (1; #21), 0.1979015966887049),
#   ("JointAverage" (1; #16), 0.19757014031671),
#   ("DifferenceVariance" (1; #8), 0.1943017998021024),
#   ("Correlation" (1; #5), 0.1940567160520604),
#   ("Imc1" (1; #13), 0.1936390081408606),
#   ("InverseVariance" (1; #15), 0.19247985591448885),
#   ("DifferenceEntropy" (1; #7), 0.18405803501235346),
#   ("Imc2" (1; #14), 0.18200690210939197),
#   ("Contrast" (1; #4), 0.1813919580304091),
#   ("DifferenceAverage" (1; #6), 0.18056750790909043),
#   ("MaximumProbability" (1; #20), 0.17937186997384716),
#   ("MCC" (1; #19), 0.17835251246818093),
#   ("ClusterTendency" (1; #3), 0.1771562112385607),
#   ("SumEntropy" (1; #22), 0.17714245059880512),
#   ("ClusterProminence" (1; #1), 0.17541568701166105),
#   ("Id" (1; #9), 0.17521382180926234),
#   ("JointEntropy" (1; #18), 0.17445929156336334),
#   ("JointEnergy" (1; #17), 0.17445304011321677),
#   ("SumSquares" (1; #23), 0.17400066571745168),
#   ("Idm" (1; #10), 0.1736827044927352)],
#  'NUM_AS_ROOT': [("Idn" (1; #12), 69.0),
#   ("Idmn" (1; #11), 57.0),
#   ("Autocorrelation" (1; #0), 25.0),
#   ("Correlation" (1; #5), 23.0),
#   ("Imc1" (1; #13), 21.0),
#   ("SumAverage" (1; #21), 21.0),
#   ("JointAverage" (1; #16), 20.0),
#   ("InverseVariance" (1; #15), 8.0),
#   ("MCC" (1; #19), 7.0),
#   ("DifferenceVariance" (1; #8), 5.0),
#   ("Imc2" (1; #14), 4.0),
#   ("ClusterShade" (1; #2), 3.0),
#   ("Contrast" (1; #4), 3.0),
#   ("DifferenceEntropy" (1; #7), 1.0)],
#  'SUM_SCORE': [("SumAverage" (1; #21), 32796.1643149279),
#   ("Autocorrelation" (1; #0), 25173.931422135993),
#   ("Correlation" (1; #5), 24538.004190574764),
#   ("JointAverage" (1; #16), 12478.33218496421),
#   ("DifferenceVariance" (1; #8), 10256.72002593585),
#   ("InverseVariance" (1; #15), 8837.410377730803),
#   ("Idn" (1; #12), 7990.88294012483),
#   ("Imc1" (1; #13), 7615.105371296523),
#   ("Idmn" (1; #11), 6646.191942051613),
#   ("Contrast" (1; #4), 3986.4350381747245),
#   ("ClusterShade" (1; #2), 3701.2623368250333),
#   ("MaximumProbability" (1; #20), 3168.348613633715),
#   ("DifferenceEntropy" (1; #7), 1818.1857515479016),
#   ("DifferenceAverage" (1; #6), 1209.0827397920514),
#   ("SumEntropy" (1; #22), 929.4147733895114),
#   ("Id" (1; #9), 865.2661692741254),
#   ("Imc2" (1; #14), 684.1595666095025),
#   ("ClusterProminence" (1; #1), 593.9488518041114),
#   ("JointEnergy" (1; #17), 541.3443070257775),
#   ("Idm" (1; #10), 484.2452612362371),
#   ("ClusterTendency" (1; #3), 446.19338360371466),
#   ("SumSquares" (1; #23), 373.1013487887683),
#   ("JointEntropy" (1; #18), 358.13850136469557),
#   ("MCC" (1; #19), 298.3120741921885)],
#  'NUM_NODES': [("Autocorrelation" (1; #0), 716.0),
#   ("ClusterShade" (1; #2), 575.0),
#   ("Idmn" (1; #11), 569.0),
#   ("Idn" (1; #12), 543.0),
#   ("SumAverage" (1; #21), 412.0),
#   ("JointAverage" (1; #16), 400.0),
#   ("InverseVariance" (1; #15), 399.0),
#   ("DifferenceVariance" (1; #8), 355.0),
#   ("Correlation" (1; #5), 316.0),
#   ("Imc1" (1; #13), 283.0),
#   ("Imc2" (1; #14), 277.0),
#   ("DifferenceEntropy" (1; #7), 235.0),
#   ("SumEntropy" (1; #22), 227.0),
#   ("MaximumProbability" (1; #20), 225.0),
#   ("Contrast" (1; #4), 205.0),
#   ("ClusterProminence" (1; #1), 188.0),
#   ("DifferenceAverage" (1; #6), 180.0),
#   ("Id" (1; #9), 144.0),
#   ("JointEnergy" (1; #17), 144.0),
#   ("MCC" (1; #19), 137.0),
#   ("ClusterTendency" (1; #3), 134.0),
#   ("SumSquares" (1; #23), 123.0),
#   ("Idm" (1; #10), 107.0),
#   ("JointEntropy" (1; #18), 102.0)]}

# %%
# Model self evaluation
model.make_inspector().evaluation()
# Out:
# Evaluation(num_examples=None, accuracy=0.9191171526908875, loss=0.42464983463287354, rmse=None, ndcg=None, aucs=None, auuc=None, qini=None)

# %%
logs = model.make_inspector().training_logs()

plt.figure(figsize=(12, 4))
plt.subplot(1, 2, 1)
plt.plot([log.num_trees for log in logs], [log.evaluation.accuracy for log in logs])
plt.xlabel("Number of trees")
plt.ylabel("Accuracy (out-of-bag)")
plt.subplot(1, 2, 2)
plt.plot([log.num_trees for log in logs], [log.evaluation.loss for log in logs])
plt.xlabel("Number of trees")
plt.ylabel("Logloss (out-of-bag)")
plt.show()

# %% [markdown]
# Calculate the score of our hold-out validation dataset

# %%
predictions = model.predict(val_ds)
y_true      = validation_data["label"]

from sklearn.metrics import roc_auc_score
ROC_AUC = roc_auc_score(y_true, predictions)
print("The ROC AUC score is %.5f" % ROC_AUC )
# Out:
#  1/23 [>.............................] - ETA: 1s
# 10/23 [============>.................] - ETA: 0s
# 18/23 [======================>.......] - ETA: 0s
# 23/23 [==============================] - 0s 6ms/step
# The ROC AUC score is 0.97702

# %%
# Compute binary classification metrics with sklearn
import numpy as np
from sklearn.metrics import (
    accuracy_score,
    precision_score,
    recall_score,
    f1_score,
    roc_auc_score,
    average_precision_score,
    confusion_matrix,
    classification_report,
    matthews_corrcoef,
    log_loss,
    brier_score_loss,
)

# Get predictions (probabilities or class labels)
preds = model.predict(test_ds)
# If model outputs probabilities, convert to labels by threshold 0.5
if preds.ndim == 2:
    # For TFDF classification, preds may be class probabilities with shape (N, 2)
    if preds.shape[1] == 2:
        pos_probs = preds[:, 1]
    else:
        # If single-probability column (positive class)
        pos_probs = preds[:, -1]
    y_pred = (pos_probs >= 0.5).astype(int)
else:
    # Already class labels
    y_pred = preds.astype(int)
    pos_probs = None

# Ground truth labels (must be 0/1 integers)
y_true = test_data["label"].astype(int).to_numpy()

# Core metrics
metrics = {}
metrics["accuracy"] = accuracy_score(y_true, y_pred)
metrics["precision"] = precision_score(y_true, y_pred, zero_division=0)
metrics["recall"] = recall_score(y_true, y_pred, zero_division=0)
metrics["f1"] = f1_score(y_true, y_pred, zero_division=0)
metrics["mcc"] = matthews_corrcoef(y_true, y_pred)

# Probabilistic metrics (only if we have probabilities)
if pos_probs is not None:
    metrics["roc_auc"] = roc_auc_score(y_true, pos_probs)
    metrics["pr_auc"] = average_precision_score(y_true, pos_probs)
    metrics["log_loss"] = log_loss(y_true, pos_probs, labels=[0,1])
    metrics["brier_score"] = brier_score_loss(y_true, pos_probs)

# Confusion matrix and detailed report
cm = confusion_matrix(y_true, y_pred, labels=[0,1])
report = classification_report(y_true, y_pred, digits=4)

print("Sklearn binary metrics:")
for k, v in metrics.items():
    print(f"{k}: {v:.4f}")
print("\nConfusion matrix:\n", cm)
print("\nClassification report:\n", report)
# Out:
#  1/45 [..............................] - ETA: 3s
# 10/45 [=====>........................] - ETA: 0s
# 19/45 [===========>..................] - ETA: 0s
# 28/45 [=================>............] - ETA: 0s
# 37/45 [=======================>......] - ETA: 0s
# 45/45 [==============================] - 0s 6ms/step
# Sklearn binary metrics:
# accuracy: 0.9328
# precision: 0.4855
# recall: 0.9082
# f1: 0.6328
# mcc: 0.6353
# roc_auc: 0.9773
# pr_auc: 0.8306
# log_loss: 0.1658
# brier_score: 0.0491
#
# Confusion matrix:
#  [[39337  2758]
#  [  263  2603]]
#
# Classification report:
#                precision    recall  f1-score   support
#
#            0     0.9934    0.9345    0.9630     42095
#            1     0.4855    0.9082    0.6328      2866
#
#     accuracy                         0.9328     44961
#    macro avg     0.7395    0.9214    0.7979     44961
# weighted avg     0.9610    0.9328    0.9420     44961
