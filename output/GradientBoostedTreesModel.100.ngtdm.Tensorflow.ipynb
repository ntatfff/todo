# %%
# Import packages and modules
import numpy  as np
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow_decision_forests as tfdf

from sklearn.model_selection import train_test_split
# Out:
# 2026-07-04 09:13:34.663413: I tensorflow/core/util/port.cc:113] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2026-07-04 09:13:34.703616: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2026-07-04 09:13:39.173292: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
# Check the version of TensorFlow Decision Forests
print("Found TensorFlow Decision Forests v" + tfdf.__version__)
# Out:
# Found TensorFlow Decision Forests v1.9.1

# %%
datasetPath = 'dataset/firstorder/kernel5-radius5/dataset.csv'

# %%
# Parameters
datasetPath = "dataset/ngtdm/kernel5-radius5/100.dataset.csv"

# %%
# train/validation/test = 70/10/20
dataset = pd.read_csv(datasetPath)

train_data, temp_data = train_test_split(dataset, test_size=0.3, random_state=42)
validation_data, test_data = train_test_split(temp_data, test_size=2/3, random_state=42)

# %%
from sklearn.utils.class_weight import compute_class_weight

# tinh class weight tren tap train
classes = np.array([0, 1])
weights = compute_class_weight(class_weight="balanced", classes=classes, y=train_data["label"])
class_weight = {0: weights[0], 1: weights[1]}

# gan sample_weight cho tung dong
train_data["sample_weight"] = train_data["label"].map(class_weight)
validation_data["sample_weight"] = validation_data["label"].map(class_weight)
test_data["sample_weight"] = test_data["label"].map(class_weight)

# Convert the dataset into a TensorFlow dataset.
train_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    train_data, label="label", weight="sample_weight"
)         
val_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    validation_data, label="label", weight="sample_weight"
)
test_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    test_data, label="label", weight="sample_weight"
)
# Out:
# 2026-07-04 09:13:52.865902: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:984] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2026-07-04 09:13:52.867878: W tensorflow/core/common_runtime/gpu/gpu_device.cc:2251] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...

# %%
import keras

# %%
# %%time

# Train a Gradient Boosted Trees model.
model = tfdf.keras.GradientBoostedTreesModel()

# Add evaluation metrics
model.compile(
    metrics=["accuracy"]
)
model.fit(x=train_ds)

# # Train a Gradient Boosted Trees model.
# model = tfdf.keras.GradientBoostedTreesModel(num_trees=1500)
# model.fit(train_ds)
# Out:
# Use /tmp/tmpw57q9gzo as temporary training directory
# Reading training dataset...
# [WARNING 26-07-04 09:13:52.9699 UTC gradient_boosted_trees.cc:1840] "goss_alpha" set but "sampling_method" not equal to "GOSS".
# [WARNING 26-07-04 09:13:52.9699 UTC gradient_boosted_trees.cc:1851] "goss_beta" set but "sampling_method" not equal to "GOSS".
# [WARNING 26-07-04 09:13:52.9699 UTC gradient_boosted_trees.cc:1865] "selective_gradient_boosting_ratio" set but "sampling_method" not equal to "SELGB".
# Training dataset read in 0:00:02.560823. Found 78712 examples.
# Training model...
# Model trained in 0:00:08.043545
# Compiling model...
# [INFO 26-07-04 09:14:03.5857 UTC kernel.cc:1233] Loading model from path /tmp/tmpw57q9gzo/model/ with prefix 12cdb93c679e4719
# [INFO 26-07-04 09:14:03.5970 UTC quick_scorer_extended.cc:911] The binary was compiled without AVX2 support, but your CPU supports it. Enable it for faster model inference.
# [INFO 26-07-04 09:14:03.5978 UTC abstract_model.cc:1362] Engine "GradientBoostedTreesQuickScorerExtended" built
# [INFO 26-07-04 09:14:03.5978 UTC kernel.cc:1061] Use fast generic engine
# Model compiled.
# CPU times: user 35.6 s, sys: 832 ms, total: 36.4 s
# Wall time: 13.6 s

# %%
# Evaluate the model
evaluate = model.evaluate(val_ds, return_dict=True)
print()

for name, value in evaluate.items():
    print(f"{name}: {value:.4f}")
# Out:
# WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
#  1/12 [=>............................] - ETA: 31s - loss: 0.0000e+00 - accuracy: 0.9070
# 12/12 [==============================] - 3s 3ms/step - loss: 0.0000e+00 - accuracy: 0.9051
# loss: 0.0000
# accuracy: 0.9051

# %%
# Model Summary
model.summary()
# Out:
# Model: "gradient_boosted_trees_model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
# =================================================================
# Total params: 1 (1.00 Byte)
# Trainable params: 0 (0.00 Byte)
# Non-trainable params: 1 (1.00 Byte)
# _________________________________________________________________
# Type: "GRADIENT_BOOSTED_TREES"
# Task: CLASSIFICATION
# Label: "__LABEL"
#
# Input Features (5):
# 	Busyness
# 	Coarseness
# 	Complexity
# 	Contrast
# 	Strength
#
# Trained with weights
#
# Variable Importance: INV_MEAN_MIN_DEPTH:
#     1.   "Busyness"  0.345363 ################
#     2.   "Contrast"  0.300896 ##########
#     3. "Complexity"  0.289031 #########
#     4. "Coarseness"  0.239456 ##
#     5.   "Strength"  0.215636
#
# Variable Importance: NUM_AS_ROOT:
#     1.   "Contrast" 79.000000 ################
#     2.   "Busyness" 72.000000 ##############
#     3. "Coarseness" 38.000000 #######
#     4. "Complexity" 19.000000 ###
#     5.   "Strength"  5.000000
#
# Variable Importance: NUM_NODES:
#     1.   "Busyness" 1457.000000 ################
#     2. "Complexity" 1151.000000 #######
#     3.   "Contrast" 1030.000000 ####
#     4. "Coarseness" 979.000000 ##
#     5.   "Strength" 871.000000
#
# Variable Importance: SUM_SCORE:
#     1. "Coarseness" 30999.666521 ################
#     2.   "Busyness" 22381.888759 ##########
#     3. "Complexity" 7121.664813 #
#     4.   "Strength" 5170.466640
#     5.   "Contrast" 4441.174972
#
#
#
# Loss: BINOMIAL_LOG_LIKELIHOOD
# Validation loss value: 0.583634
# Number of trees per iteration: 1
# Node format: NOT_SET
# Number of trees: 213
# Total number of nodes: 11189
#
# Number of nodes by tree:
# Count: 213 Average: 52.5305 StdDev: 7.95794
# Min: 27 Max: 63 Ignored: 0
# ----------------------------------------------
# [ 27, 28)  1   0.47%   0.47%
# [ 28, 30)  0   0.00%   0.47%
# [ 30, 32)  2   0.94%   1.41% #
# [ 32, 34)  1   0.47%   1.88%
# [ 34, 36)  3   1.41%   3.29% #
# [ 36, 38)  3   1.41%   4.69% #
# [ 38, 39)  0   0.00%   4.69%
# [ 39, 41)  4   1.88%   6.57% #
# [ 41, 43)  4   1.88%   8.45% #
# [ 43, 45) 10   4.69%  13.15% ###
# [ 45, 47) 17   7.98%  21.13% ######
# [ 47, 49) 20   9.39%  30.52% #######
# [ 49, 51) 17   7.98%  38.50% ######
# [ 51, 52) 20   9.39%  47.89% #######
# [ 52, 54) 12   5.63%  53.52% ####
# [ 54, 56) 14   6.57%  60.09% #####
# [ 56, 58) 22  10.33%  70.42% ########
# [ 58, 60)  9   4.23%  74.65% ###
# [ 60, 62) 25  11.74%  86.38% #########
# [ 62, 63] 29  13.62% 100.00% ##########
#
# Depth by leafs:
# Count: 5701 Average: 4.86283 StdDev: 0.466137
# Min: 1 Max: 5 Ignored: 0
# ----------------------------------------------
# [ 1, 2)    2   0.04%   0.04%
# [ 2, 3)   41   0.72%   0.75%
# [ 3, 4)  147   2.58%   3.33%
# [ 4, 5)  357   6.26%   9.59% #
# [ 5, 5] 5154  90.41% 100.00% ##########
#
# Number of training obs by leaf:
# Count: 5701 Average: 2646.71 StdDev: 8820.01
# Min: 5 Max: 70174 Ignored: 0
# ----------------------------------------------
# [     5,  3513) 5005  87.79%  87.79% ##########
# [  3513,  7022)  220   3.86%  91.65%
# [  7022, 10530)  116   2.03%  93.69%
# [ 10530, 14039)   60   1.05%  94.74%
# [ 14039, 17547)   39   0.68%  95.42%
# [ 17547, 21056)   42   0.74%  96.16%
# [ 21056, 24564)   31   0.54%  96.70%
# [ 24564, 28073)   36   0.63%  97.33%
# [ 28073, 31581)   16   0.28%  97.61%
# [ 31581, 35090)   15   0.26%  97.88%
# [ 35090, 38598)   14   0.25%  98.12%
# [ 38598, 42107)    6   0.11%  98.23%
# [ 42107, 45615)   10   0.18%  98.40%
# [ 45615, 49124)   18   0.32%  98.72%
# [ 49124, 52632)   14   0.25%  98.97%
# [ 52632, 56141)    3   0.05%  99.02%
# [ 56141, 59649)   12   0.21%  99.23%
# [ 59649, 63158)   15   0.26%  99.49%
# [ 63158, 66666)    9   0.16%  99.65%
# [ 66666, 70174]   20   0.35% 100.00%
#
# Attribute in nodes:
# 	1457 : Busyness [NUMERICAL]
# 	1151 : Complexity [NUMERICAL]
# 	1030 : Contrast [NUMERICAL]
# 	979 : Coarseness [NUMERICAL]
# 	871 : Strength [NUMERICAL]
#
# Attribute in nodes with depth <= 0:
# 	79 : Contrast [NUMERICAL]
# 	72 : Busyness [NUMERICAL]
# 	38 : Coarseness [NUMERICAL]
# 	19 : Complexity [NUMERICAL]
# 	5 : Strength [NUMERICAL]
#
# Attribute in nodes with depth <= 1:
# 	193 : Busyness [NUMERICAL]
# 	160 : Complexity [NUMERICAL]
# 	144 : Contrast [NUMERICAL]
# 	86 : Coarseness [NUMERICAL]
# 	54 : Strength [NUMERICAL]
#
# Attribute in nodes with depth <= 2:
# 	420 : Busyness [NUMERICAL]
# 	376 : Complexity [NUMERICAL]
# 	304 : Contrast [NUMERICAL]
# 	184 : Coarseness [NUMERICAL]
# 	160 : Strength [NUMERICAL]
#
# Attribute in nodes with depth <= 3:
# 	779 : Busyness [NUMERICAL]
# 	659 : Complexity [NUMERICAL]
# 	589 : Contrast [NUMERICAL]
# 	445 : Coarseness [NUMERICAL]
# 	439 : Strength [NUMERICAL]
#
# Attribute in nodes with depth <= 5:
# 	1457 : Busyness [NUMERICAL]
# 	1151 : Complexity [NUMERICAL]
# 	1030 : Contrast [NUMERICAL]
# 	979 : Coarseness [NUMERICAL]
# 	871 : Strength [NUMERICAL]
#
# Condition type in nodes:
# 	5488 : HigherCondition
# Condition type in nodes with depth <= 0:
# 	213 : HigherCondition
# Condition type in nodes with depth <= 1:
# 	637 : HigherCondition
# Condition type in nodes with depth <= 2:
# 	1444 : HigherCondition
# Condition type in nodes with depth <= 3:
# 	2911 : HigherCondition
# Condition type in nodes with depth <= 5:
# 	5488 : HigherCondition
#
# Training logs:
# Number of iteration to final model: 213
# 	Iter:1 train-loss:1.287839 valid-loss:1.286915  train-accuracy:0.836962 valid-accuracy:0.839927
# 	Iter:2 train-loss:1.205483 valid-loss:1.204478  train-accuracy:0.841893 valid-accuracy:0.841307
# 	Iter:3 train-loss:1.135491 valid-loss:1.134174  train-accuracy:0.842963 valid-accuracy:0.844470
# 	Iter:4 train-loss:1.078060 valid-loss:1.075889  train-accuracy:0.843763 valid-accuracy:0.848507
# 	Iter:5 train-loss:1.026882 valid-loss:1.024495  train-accuracy:0.847536 valid-accuracy:0.846930
# 	Iter:6 train-loss:0.984930 valid-loss:0.982692  train-accuracy:0.850245 valid-accuracy:0.851155
# 	Iter:16 train-loss:0.753069 valid-loss:0.755857  train-accuracy:0.859832 valid-accuracy:0.860073
# 	Iter:26 train-loss:0.672768 valid-loss:0.686787  train-accuracy:0.864646 valid-accuracy:0.867725
# 	Iter:36 train-loss:0.627561 valid-loss:0.651792  train-accuracy:0.871147 valid-accuracy:0.868986
# 	Iter:46 train-loss:0.595173 valid-loss:0.631325  train-accuracy:0.877615 valid-accuracy:0.869334
# 	Iter:56 train-loss:0.574495 valid-loss:0.620280  train-accuracy:0.882332 valid-accuracy:0.872846
# 	Iter:66 train-loss:0.558222 valid-loss:0.614128  train-accuracy:0.885622 valid-accuracy:0.871686
# 	Iter:76 train-loss:0.542563 valid-loss:0.609544  train-accuracy:0.889743 valid-accuracy:0.872381
# 	Iter:86 train-loss:0.529039 valid-loss:0.603023  train-accuracy:0.892343 valid-accuracy:0.876102
# 	Iter:96 train-loss:0.518688 valid-loss:0.599547  train-accuracy:0.894429 valid-accuracy:0.876033
# 	Iter:106 train-loss:0.508924 valid-loss:0.598091  train-accuracy:0.896837 valid-accuracy:0.874039
# 	Iter:116 train-loss:0.501030 valid-loss:0.596185  train-accuracy:0.899078 valid-accuracy:0.874108
# 	Iter:126 train-loss:0.492358 valid-loss:0.593659  train-accuracy:0.900924 valid-accuracy:0.875696
# 	Iter:136 train-loss:0.485501 valid-loss:0.591206  train-accuracy:0.903175 valid-accuracy:0.879209
# 	Iter:146 train-loss:0.478117 valid-loss:0.589319  train-accuracy:0.905136 valid-accuracy:0.877770
# 	Iter:156 train-loss:0.471038 valid-loss:0.588653  train-accuracy:0.907072 valid-accuracy:0.879219
# 	Iter:166 train-loss:0.463732 valid-loss:0.587371  train-accuracy:0.908795 valid-accuracy:0.880112
# 	Iter:176 train-loss:0.456047 valid-loss:0.585698  train-accuracy:0.911182 valid-accuracy:0.879369
# 	Iter:186 train-loss:0.449973 valid-loss:0.583867  train-accuracy:0.912427 valid-accuracy:0.880342
# 	Iter:196 train-loss:0.444674 valid-loss:0.583966  train-accuracy:0.914145 valid-accuracy:0.880550
# 	Iter:206 train-loss:0.438322 valid-loss:0.584252  train-accuracy:0.915405 valid-accuracy:0.879668
# 	Iter:216 train-loss:0.432088 valid-loss:0.584149  train-accuracy:0.917703 valid-accuracy:0.880433
# 	Iter:226 train-loss:0.426483 valid-loss:0.584294  train-accuracy:0.919654 valid-accuracy:0.879133
# 	Iter:236 train-loss:0.421774 valid-loss:0.584213  train-accuracy:0.921130 valid-accuracy:0.879957

# %%
# Model features
model.make_inspector().features()
# Out:
# ["Busyness" (1; #0),
#  "Coarseness" (1; #1),
#  "Complexity" (1; #2),
#  "Contrast" (1; #3),
#  "Strength" (1; #4)]

# %%
# Feature importance
model.make_inspector().variable_importances()
# Out:
# {'INV_MEAN_MIN_DEPTH': [("Busyness" (1; #0), 0.3453633574673984),
#   ("Contrast" (1; #3), 0.3008963519252411),
#   ("Complexity" (1; #2), 0.2890307573325866),
#   ("Coarseness" (1; #1), 0.23945606650697213),
#   ("Strength" (1; #4), 0.21563597364787376)],
#  'SUM_SCORE': [("Coarseness" (1; #1), 30999.66652123894),
#   ("Busyness" (1; #0), 22381.88875946566),
#   ("Complexity" (1; #2), 7121.664813256843),
#   ("Strength" (1; #4), 5170.466639684222),
#   ("Contrast" (1; #3), 4441.17497171052)],
#  'NUM_AS_ROOT': [("Contrast" (1; #3), 79.0),
#   ("Busyness" (1; #0), 72.0),
#   ("Coarseness" (1; #1), 38.0),
#   ("Complexity" (1; #2), 19.0),
#   ("Strength" (1; #4), 5.0)],
#  'NUM_NODES': [("Busyness" (1; #0), 1457.0),
#   ("Complexity" (1; #2), 1151.0),
#   ("Contrast" (1; #3), 1030.0),
#   ("Coarseness" (1; #1), 979.0),
#   ("Strength" (1; #4), 871.0)]}

# %%
# Model self evaluation
model.make_inspector().evaluation()
# Out:
# Evaluation(num_examples=None, accuracy=0.8800850510597229, loss=0.5836343169212341, rmse=None, ndcg=None, aucs=None, auuc=None, qini=None)

# %%
logs = model.make_inspector().training_logs()

plt.figure(figsize=(12, 4))
plt.subplot(1, 2, 1)
plt.plot([log.num_trees for log in logs], [log.evaluation.accuracy for log in logs])
plt.xlabel("Number of trees")
plt.ylabel("Accuracy (out-of-bag)")
plt.subplot(1, 2, 2)
plt.plot([log.num_trees for log in logs], [log.evaluation.loss for log in logs])
plt.xlabel("Number of trees")
plt.ylabel("Logloss (out-of-bag)")
plt.show()

# %% [markdown]
# Calculate the score of our hold-out validation dataset

# %%
predictions = model.predict(val_ds)
y_true      = validation_data["label"]

from sklearn.metrics import roc_auc_score
ROC_AUC = roc_auc_score(y_true, predictions)
print("The ROC AUC score is %.5f" % ROC_AUC )
# Out:
#  1/12 [=>............................] - ETA: 0s
# 12/12 [==============================] - 0s 3ms/step
# The ROC AUC score is 0.93481

# %%
# Compute binary classification metrics with sklearn
import numpy as np
from sklearn.metrics import (
    accuracy_score,
    precision_score,
    recall_score,
    f1_score,
    roc_auc_score,
    average_precision_score,
    confusion_matrix,
    classification_report,
    matthews_corrcoef,
    log_loss,
    brier_score_loss,
)

# Get predictions (probabilities or class labels)
preds = model.predict(test_ds)
# If model outputs probabilities, convert to labels by threshold 0.5
if preds.ndim == 2:
    # For TFDF classification, preds may be class probabilities with shape (N, 2)
    if preds.shape[1] == 2:
        pos_probs = preds[:, 1]
    else:
        # If single-probability column (positive class)
        pos_probs = preds[:, -1]
    y_pred = (pos_probs >= 0.5).astype(int)
else:
    # Already class labels
    y_pred = preds.astype(int)
    pos_probs = None

# Ground truth labels (must be 0/1 integers)
y_true = test_data["label"].astype(int).to_numpy()

# Core metrics
metrics = {}
metrics["accuracy"] = accuracy_score(y_true, y_pred)
metrics["precision"] = precision_score(y_true, y_pred, zero_division=0)
metrics["recall"] = recall_score(y_true, y_pred, zero_division=0)
metrics["f1"] = f1_score(y_true, y_pred, zero_division=0)
metrics["mcc"] = matthews_corrcoef(y_true, y_pred)

# Probabilistic metrics (only if we have probabilities)
if pos_probs is not None:
    metrics["roc_auc"] = roc_auc_score(y_true, pos_probs)
    metrics["pr_auc"] = average_precision_score(y_true, pos_probs)
    metrics["log_loss"] = log_loss(y_true, pos_probs, labels=[0,1])
    metrics["brier_score"] = brier_score_loss(y_true, pos_probs)

# Confusion matrix and detailed report
cm = confusion_matrix(y_true, y_pred, labels=[0,1])
report = classification_report(y_true, y_pred, digits=4)

print("Sklearn binary metrics:")
for k, v in metrics.items():
    print(f"{k}: {v:.4f}")
print("\nConfusion matrix:\n", cm)
print("\nClassification report:\n", report)
# Out:
#  1/23 [>.............................] - ETA: 1s
# 16/23 [===================>..........] - ETA: 0s
# 23/23 [==============================] - 0s 3ms/step
# Sklearn binary metrics:
# accuracy: 0.9048
# precision: 0.4213
# recall: 0.8091
# f1: 0.5541
# mcc: 0.5406
# roc_auc: 0.9396
# pr_auc: 0.7333
# log_loss: 0.2490
# brier_score: 0.0725
#
# Confusion matrix:
#  [[19017  1828]
#  [  314  1331]]
#
# Classification report:
#                precision    recall  f1-score   support
#
#            0     0.9838    0.9123    0.9467     20845
#            1     0.4213    0.8091    0.5541      1645
#
#     accuracy                         0.9048     22490
#    macro avg     0.7025    0.8607    0.7504     22490
# weighted avg     0.9426    0.9048    0.9180     22490
