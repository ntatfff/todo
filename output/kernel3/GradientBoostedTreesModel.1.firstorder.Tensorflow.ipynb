# %%
# Import packages and modules
import numpy  as np
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow_decision_forests as tfdf

from sklearn.model_selection import train_test_split
# Out:
# 2026-08-15 04:53:36.870064: I tensorflow/core/util/port.cc:113] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2026-08-15 04:53:43.470641: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2026-08-15 04:54:01.154699: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
# Check the version of TensorFlow Decision Forests
print("Found TensorFlow Decision Forests v" + tfdf.__version__)
# Out:
# Found TensorFlow Decision Forests v1.9.1

# %%
datasetPath = 'dataset/firstorder/kernel5/dataset.csv'

# %%
# Parameters
datasetPath = "dataset/firstorder/kernel3/1.dataset.csv"

# %%
# train/validation/test = 70/10/20
dataset = pd.read_csv(datasetPath)

train_data, temp_data = train_test_split(dataset, test_size=0.3, random_state=42)
validation_data, test_data = train_test_split(temp_data, test_size=2/3, random_state=42)

# %%
from sklearn.utils.class_weight import compute_class_weight

# tinh class weight tren tap train
classes = np.array([0, 1])
weights = compute_class_weight(class_weight="balanced", classes=classes, y=train_data["label"])
class_weight = {0: weights[0], 1: weights[1]}

# gan sample_weight cho tung dong
train_data["sample_weight"] = train_data["label"].map(class_weight)
validation_data["sample_weight"] = validation_data["label"].map(class_weight)
test_data["sample_weight"] = test_data["label"].map(class_weight)

# Convert the dataset into a TensorFlow dataset.
train_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    train_data, label="label", weight="sample_weight"
)         
val_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    validation_data, label="label", weight="sample_weight"
)
test_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    test_data, label="label", weight="sample_weight"
)
# Out:
# 2026-08-15 04:54:37.670684: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:984] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2026-08-15 04:54:37.672907: W tensorflow/core/common_runtime/gpu/gpu_device.cc:2251] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...

# %%
import keras

# %%
# %%time

# Train a Gradient Boosted Trees model.
model = tfdf.keras.GradientBoostedTreesModel()

# Add evaluation metrics
model.compile(
    metrics=["accuracy"]
)
model.fit(x=train_ds)

# # Train a Gradient Boosted Trees model.
# model = tfdf.keras.GradientBoostedTreesModel(num_trees=1500)
# model.fit(train_ds)
# Out:
# Use /tmp/tmpa5qmf6no as temporary training directory
# Reading training dataset...
# [WARNING 26-08-15 04:54:38.3098 UTC gradient_boosted_trees.cc:1840] "goss_alpha" set but "sampling_method" not equal to "GOSS".
# [WARNING 26-08-15 04:54:38.3135 UTC gradient_boosted_trees.cc:1851] "goss_beta" set but "sampling_method" not equal to "GOSS".
# [WARNING 26-08-15 04:54:38.3135 UTC gradient_boosted_trees.cc:1865] "selective_gradient_boosting_ratio" set but "sampling_method" not equal to "SELGB".
# Training dataset read in 0:00:03.451000. Found 3308 examples.
# Training model...
# Model trained in 0:00:00.654517
# Compiling model...
# [INFO 26-08-15 04:54:42.5986 UTC kernel.cc:1233] Loading model from path /tmp/tmpa5qmf6no/model/ with prefix 37512fee937a47e4
# [INFO 26-08-15 04:54:42.6016 UTC quick_scorer_extended.cc:911] The binary was compiled without AVX2 support, but your CPU supports it. Enable it for faster model inference.
# [INFO 26-08-15 04:54:42.6017 UTC abstract_model.cc:1362] Engine "GradientBoostedTreesQuickScorerExtended" built
# [INFO 26-08-15 04:54:42.6018 UTC kernel.cc:1061] Use fast generic engine
# Model compiled.
# CPU times: user 6.48 s, sys: 381 ms, total: 6.86 s
# Wall time: 8.16 s

# %%
# Evaluate the model
evaluate = model.evaluate(val_ds, return_dict=True)
print()

for name, value in evaluate.items():
    print(f"{name}: {value:.4f}")
# Out:
# WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 1/1 [==============================] - ETA: 0s - loss: 0.0000e+00 - accuracy: 0.9894
# 1/1 [==============================] - 3s 3s/step - loss: 0.0000e+00 - accuracy: 0.9894
# loss: 0.0000
# accuracy: 0.9894

# %%
# Model Summary
model.summary()
# Out:
# Model: "gradient_boosted_trees_model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
# =================================================================
# Total params: 1 (1.00 Byte)
# Trainable params: 0 (0.00 Byte)
# Non-trainable params: 1 (1.00 Byte)
# _________________________________________________________________
# Type: "GRADIENT_BOOSTED_TREES"
# Task: CLASSIFICATION
# Label: "__LABEL"
#
# Input Features (18):
# 	10Percentile
# 	90Percentile
# 	Energy
# 	Entropy
# 	InterquartileRange
# 	Kurtosis
# 	Maximum
# 	Mean
# 	MeanAbsoluteDeviation
# 	Median
# 	Minimum
# 	Range
# 	RobustMeanAbsoluteDeviation
# 	RootMeanSquared
# 	Skewness
# 	TotalEnergy
# 	Uniformity
# 	Variance
#
# Trained with weights
#
# Variable Importance: INV_MEAN_MIN_DEPTH:
#     1.                "90Percentile"  0.732676 ################
#     2.                     "Maximum"  0.231459 #
#     3.                    "Skewness"  0.204485
#     4.                  "Uniformity"  0.204390
#     5.                      "Median"  0.204386
#     6.                     "Minimum"  0.196614
#     7.                        "Mean"  0.195407
#     8.                     "Entropy"  0.193578
#     9.                       "Range"  0.190322
#    10.                "10Percentile"  0.188637
#    11. "RobustMeanAbsoluteDeviation"  0.185314
#    12.                      "Energy"  0.184933
#    13.                    "Variance"  0.182987
#    14.                    "Kurtosis"  0.182945
#    15.                 "TotalEnergy"  0.182806
#    16.             "RootMeanSquared"  0.182706
#    17.       "MeanAbsoluteDeviation"  0.182320
#    18.          "InterquartileRange"  0.181413
#
# Variable Importance: NUM_AS_ROOT:
#     1. "90Percentile" 25.000000 ################
#     2.      "Maximum"  4.000000
#
# Variable Importance: NUM_NODES:
#     1.                "90Percentile" 121.000000 ################
#     2.                    "Skewness" 57.000000 #######
#     3.                  "Uniformity" 47.000000 #####
#     4.                     "Entropy" 42.000000 #####
#     5.                      "Median" 41.000000 ####
#     6.                        "Mean" 38.000000 ####
#     7.                     "Maximum" 35.000000 ####
#     8.                     "Minimum" 35.000000 ####
#     9.                       "Range" 34.000000 ###
#    10.                "10Percentile" 20.000000 #
#    11.                    "Kurtosis" 16.000000 #
#    12.                      "Energy" 15.000000 #
#    13. "RobustMeanAbsoluteDeviation" 14.000000 #
#    14.             "RootMeanSquared" 11.000000
#    15.                 "TotalEnergy" 10.000000
#    16.                    "Variance"  7.000000
#    17.          "InterquartileRange"  6.000000
#    18.       "MeanAbsoluteDeviation"  6.000000
#
# Variable Importance: SUM_SCORE:
#     1.                "90Percentile" 3636.726396 ################
#     2.                    "Skewness" 68.219216
#     3.                  "Uniformity" 66.840365
#     4.                        "Mean" 58.490376
#     5.                "10Percentile" 43.398882
#     6.                     "Maximum" 40.947473
#     7.                     "Entropy" 28.996693
#     8.                     "Minimum" 19.232574
#     9.                      "Median" 12.549166
#    10.                    "Kurtosis"  9.010146
#    11.                       "Range"  6.217743
#    12.                      "Energy"  5.316059
#    13.                 "TotalEnergy"  4.195816
#    14. "RobustMeanAbsoluteDeviation"  2.404713
#    15.       "MeanAbsoluteDeviation"  2.208226
#    16.                    "Variance"  1.109183
#    17.          "InterquartileRange"  0.398930
#    18.             "RootMeanSquared"  0.113504
#
#
#
# Loss: BINOMIAL_LOG_LIKELIHOOD
# Validation loss value: 0.249591
# Number of trees per iteration: 1
# Node format: NOT_SET
# Number of trees: 29
# Total number of nodes: 1139
#
# Number of nodes by tree:
# Count: 29 Average: 39.2759 StdDev: 4.02489
# Min: 29 Max: 49 Ignored: 0
# ----------------------------------------------
# [ 29, 30)  1   3.45%   3.45% #
# [ 30, 31)  0   0.00%   3.45%
# [ 31, 32)  0   0.00%   3.45%
# [ 32, 33)  0   0.00%   3.45%
# [ 33, 34)  0   0.00%   3.45%
# [ 34, 35)  0   0.00%   3.45%
# [ 35, 36)  5  17.24%  20.69% #####
# [ 36, 37)  0   0.00%  20.69%
# [ 37, 38)  3  10.34%  31.03% ###
# [ 38, 39)  0   0.00%  31.03%
# [ 39, 40) 10  34.48%  65.52% ##########
# [ 40, 41)  0   0.00%  65.52%
# [ 41, 42)  5  17.24%  82.76% #####
# [ 42, 43)  0   0.00%  82.76%
# [ 43, 44)  2   6.90%  89.66% ##
# [ 44, 45)  0   0.00%  89.66%
# [ 45, 46)  0   0.00%  89.66%
# [ 46, 47)  0   0.00%  89.66%
# [ 47, 48)  2   6.90%  96.55% ##
# [ 48, 49]  1   3.45% 100.00% #
#
# Depth by leafs:
# Count: 584 Average: 4.54281 StdDev: 0.70338
# Min: 2 Max: 5 Ignored: 0
# ----------------------------------------------
# [ 2, 3)   5   0.86%   0.86%
# [ 3, 4)  57   9.76%  10.62% #
# [ 4, 5) 138  23.63%  34.25% ####
# [ 5, 5] 384  65.75% 100.00% ##########
#
# Number of training obs by leaf:
# Count: 584 Average: 148.526 StdDev: 506.96
# Min: 5 Max: 2735 Ignored: 0
# ----------------------------------------------
# [    5,  141) 518  88.70%  88.70% ##########
# [  141,  278)  29   4.97%  93.66% #
# [  278,  414)   1   0.17%  93.84%
# [  414,  551)   5   0.86%  94.69%
# [  551,  687)   0   0.00%  94.69%
# [  687,  824)   1   0.17%  94.86%
# [  824,  960)   0   0.00%  94.86%
# [  960, 1097)   1   0.17%  95.03%
# [ 1097, 1233)   0   0.00%  95.03%
# [ 1233, 1370)   0   0.00%  95.03%
# [ 1370, 1507)   1   0.17%  95.21%
# [ 1507, 1643)   0   0.00%  95.21%
# [ 1643, 1780)   1   0.17%  95.38%
# [ 1780, 1916)   0   0.00%  95.38%
# [ 1916, 2053)   3   0.51%  95.89%
# [ 2053, 2189)   3   0.51%  96.40%
# [ 2189, 2326)   0   0.00%  96.40%
# [ 2326, 2462)   7   1.20%  97.60%
# [ 2462, 2599)  13   2.23%  99.83%
# [ 2599, 2735]   1   0.17% 100.00%
#
# Attribute in nodes:
# 	121 : 90Percentile [NUMERICAL]
# 	57 : Skewness [NUMERICAL]
# 	47 : Uniformity [NUMERICAL]
# 	42 : Entropy [NUMERICAL]
# 	41 : Median [NUMERICAL]
# 	38 : Mean [NUMERICAL]
# 	35 : Minimum [NUMERICAL]
# 	35 : Maximum [NUMERICAL]
# 	34 : Range [NUMERICAL]
# 	20 : 10Percentile [NUMERICAL]
# 	16 : Kurtosis [NUMERICAL]
# 	15 : Energy [NUMERICAL]
# 	14 : RobustMeanAbsoluteDeviation [NUMERICAL]
# 	11 : RootMeanSquared [NUMERICAL]
# 	10 : TotalEnergy [NUMERICAL]
# 	7 : Variance [NUMERICAL]
# 	6 : MeanAbsoluteDeviation [NUMERICAL]
# 	6 : InterquartileRange [NUMERICAL]
#
# Attribute in nodes with depth <= 0:
# 	25 : 90Percentile [NUMERICAL]
# 	4 : Maximum [NUMERICAL]
#
# Attribute in nodes with depth <= 1:
# 	61 : 90Percentile [NUMERICAL]
# 	13 : Maximum [NUMERICAL]
# 	8 : Median [NUMERICAL]
# 	3 : Minimum [NUMERICAL]
# 	1 : Uniformity [NUMERICAL]
# 	1 : 10Percentile [NUMERICAL]
#
# Attribute in nodes with depth <= 2:
# 	82 : 90Percentile [NUMERICAL]
# 	22 : Maximum [NUMERICAL]
# 	19 : Uniformity [NUMERICAL]
# 	14 : Mean [NUMERICAL]
# 	12 : Median [NUMERICAL]
# 	10 : Skewness [NUMERICAL]
# 	8 : Range [NUMERICAL]
# 	6 : RobustMeanAbsoluteDeviation [NUMERICAL]
# 	6 : Minimum [NUMERICAL]
# 	4 : Entropy [NUMERICAL]
# 	4 : Energy [NUMERICAL]
# 	4 : 10Percentile [NUMERICAL]
# 	2 : Variance [NUMERICAL]
# 	2 : RootMeanSquared [NUMERICAL]
# 	2 : MeanAbsoluteDeviation [NUMERICAL]
# 	1 : TotalEnergy [NUMERICAL]
#
# Attribute in nodes with depth <= 3:
# 	95 : 90Percentile [NUMERICAL]
# 	39 : Skewness [NUMERICAL]
# 	31 : Mean [NUMERICAL]
# 	29 : Uniformity [NUMERICAL]
# 	29 : Entropy [NUMERICAL]
# 	25 : Median [NUMERICAL]
# 	25 : Maximum [NUMERICAL]
# 	19 : Range [NUMERICAL]
# 	17 : Minimum [NUMERICAL]
# 	13 : 10Percentile [NUMERICAL]
# 	9 : Energy [NUMERICAL]
# 	8 : RobustMeanAbsoluteDeviation [NUMERICAL]
# 	7 : RootMeanSquared [NUMERICAL]
# 	5 : Kurtosis [NUMERICAL]
# 	4 : TotalEnergy [NUMERICAL]
# 	4 : MeanAbsoluteDeviation [NUMERICAL]
# 	3 : Variance [NUMERICAL]
# 	1 : InterquartileRange [NUMERICAL]
#
# Attribute in nodes with depth <= 5:
# 	121 : 90Percentile [NUMERICAL]
# 	57 : Skewness [NUMERICAL]
# 	47 : Uniformity [NUMERICAL]
# 	42 : Entropy [NUMERICAL]
# 	41 : Median [NUMERICAL]
# 	38 : Mean [NUMERICAL]
# 	35 : Minimum [NUMERICAL]
# 	35 : Maximum [NUMERICAL]
# 	34 : Range [NUMERICAL]
# 	20 : 10Percentile [NUMERICAL]
# 	16 : Kurtosis [NUMERICAL]
# 	15 : Energy [NUMERICAL]
# 	14 : RobustMeanAbsoluteDeviation [NUMERICAL]
# 	11 : RootMeanSquared [NUMERICAL]
# 	10 : TotalEnergy [NUMERICAL]
# 	7 : Variance [NUMERICAL]
# 	6 : MeanAbsoluteDeviation [NUMERICAL]
# 	6 : InterquartileRange [NUMERICAL]
#
# Condition type in nodes:
# 	555 : HigherCondition
# Condition type in nodes with depth <= 0:
# 	29 : HigherCondition
# Condition type in nodes with depth <= 1:
# 	87 : HigherCondition
# Condition type in nodes with depth <= 2:
# 	198 : HigherCondition
# Condition type in nodes with depth <= 3:
# 	363 : HigherCondition
# Condition type in nodes with depth <= 5:
# 	555 : HigherCondition
#
# Training logs:
# Number of iteration to final model: 29
# 	Iter:1 train-loss:1.200117 valid-loss:1.214559  train-accuracy:0.994549 valid-accuracy:0.959245
# 	Iter:2 train-loss:1.047725 valid-loss:1.072694  train-accuracy:0.994549 valid-accuracy:0.959245
# 	Iter:3 train-loss:0.920636 valid-loss:0.954816  train-accuracy:0.994549 valid-accuracy:0.961079
# 	Iter:4 train-loss:0.813387 valid-loss:0.857598  train-accuracy:0.995252 valid-accuracy:0.961079
# 	Iter:5 train-loss:0.721628 valid-loss:0.776024  train-accuracy:0.994549 valid-accuracy:0.961079
# 	Iter:6 train-loss:0.642755 valid-loss:0.706088  train-accuracy:0.995252 valid-accuracy:0.961079
# 	Iter:16 train-loss:0.231370 valid-loss:0.350062  train-accuracy:0.995955 valid-accuracy:0.962912
# 	Iter:26 train-loss:0.095234 valid-loss:0.261348  train-accuracy:0.997010 valid-accuracy:0.964745
# 	Iter:36 train-loss:0.045077 valid-loss:0.269890  train-accuracy:0.998417 valid-accuracy:0.964745
# 	Iter:46 train-loss:0.024212 valid-loss:0.294670  train-accuracy:0.998593 valid-accuracy:0.964745
# 	Iter:56 train-loss:0.015548 valid-loss:0.306645  train-accuracy:0.998945 valid-accuracy:0.966579

# %%
# Model features
model.make_inspector().features()
# Out:
# ["10Percentile" (1; #0),
#  "90Percentile" (1; #1),
#  "Energy" (1; #2),
#  "Entropy" (1; #3),
#  "InterquartileRange" (1; #4),
#  "Kurtosis" (1; #5),
#  "Maximum" (1; #6),
#  "Mean" (1; #7),
#  "MeanAbsoluteDeviation" (1; #8),
#  "Median" (1; #9),
#  "Minimum" (1; #10),
#  "Range" (1; #11),
#  "RobustMeanAbsoluteDeviation" (1; #12),
#  "RootMeanSquared" (1; #13),
#  "Skewness" (1; #14),
#  "TotalEnergy" (1; #15),
#  "Uniformity" (1; #16),
#  "Variance" (1; #17)]

# %%
# Feature importance
model.make_inspector().variable_importances()
# Out:
# {'INV_MEAN_MIN_DEPTH': [("90Percentile" (1; #1), 0.7326756496631376),
#   ("Maximum" (1; #6), 0.23145908011219907),
#   ("Skewness" (1; #14), 0.20448505778442122),
#   ("Uniformity" (1; #16), 0.2043902049097675),
#   ("Median" (1; #9), 0.20438559470665163),
#   ("Minimum" (1; #10), 0.1966139294004595),
#   ("Mean" (1; #7), 0.19540745927213748),
#   ("Entropy" (1; #3), 0.1935776059155765),
#   ("Range" (1; #11), 0.1903222983162902),
#   ("10Percentile" (1; #0), 0.18863741451986604),
#   ("RobustMeanAbsoluteDeviation" (1; #12), 0.18531407806872216),
#   ("Energy" (1; #2), 0.18493344967782496),
#   ("Variance" (1; #17), 0.18298689324263398),
#   ("Kurtosis" (1; #5), 0.18294473059318306),
#   ("TotalEnergy" (1; #15), 0.18280604718744556),
#   ("RootMeanSquared" (1; #13), 0.182705885489828),
#   ("MeanAbsoluteDeviation" (1; #8), 0.18231988267236665),
#   ("InterquartileRange" (1; #4), 0.18141346388849153)],
#  'SUM_SCORE': [("90Percentile" (1; #1), 3636.7263964612807),
#   ("Skewness" (1; #14), 68.21921642187375),
#   ("Uniformity" (1; #16), 66.84036541155993),
#   ("Mean" (1; #7), 58.49037596357117),
#   ("10Percentile" (1; #0), 43.3988818585289),
#   ("Maximum" (1; #6), 40.947472615548456),
#   ("Entropy" (1; #3), 28.996693493224026),
#   ("Minimum" (1; #10), 19.232573531572967),
#   ("Median" (1; #9), 12.549165736828682),
#   ("Kurtosis" (1; #5), 9.010146241226344),
#   ("Range" (1; #11), 6.217742689334898),
#   ("Energy" (1; #2), 5.316058734866792),
#   ("TotalEnergy" (1; #15), 4.195816229325225),
#   ("RobustMeanAbsoluteDeviation" (1; #12), 2.4047125314084052),
#   ("MeanAbsoluteDeviation" (1; #8), 2.208226183374613),
#   ("Variance" (1; #17), 1.1091831869186952),
#   ("InterquartileRange" (1; #4), 0.39892991544349365),
#   ("RootMeanSquared" (1; #13), 0.11350411087043288)],
#  'NUM_AS_ROOT': [("90Percentile" (1; #1), 25.0), ("Maximum" (1; #6), 4.0)],
#  'NUM_NODES': [("90Percentile" (1; #1), 121.0),
#   ("Skewness" (1; #14), 57.0),
#   ("Uniformity" (1; #16), 47.0),
#   ("Entropy" (1; #3), 42.0),
#   ("Median" (1; #9), 41.0),
#   ("Mean" (1; #7), 38.0),
#   ("Maximum" (1; #6), 35.0),
#   ("Minimum" (1; #10), 35.0),
#   ("Range" (1; #11), 34.0),
#   ("10Percentile" (1; #0), 20.0),
#   ("Kurtosis" (1; #5), 16.0),
#   ("Energy" (1; #2), 15.0),
#   ("RobustMeanAbsoluteDeviation" (1; #12), 14.0),
#   ("RootMeanSquared" (1; #13), 11.0),
#   ("TotalEnergy" (1; #15), 10.0),
#   ("Variance" (1; #17), 7.0),
#   ("InterquartileRange" (1; #4), 6.0),
#   ("MeanAbsoluteDeviation" (1; #8), 6.0)]}

# %%
# Model self evaluation
model.make_inspector().evaluation()
# Out:
# Evaluation(num_examples=None, accuracy=0.9647454023361206, loss=0.24959097802639008, rmse=None, ndcg=None, aucs=None, auuc=None, qini=None)

# %%
logs = model.make_inspector().training_logs()

plt.figure(figsize=(12, 4))
plt.subplot(1, 2, 1)
plt.plot([log.num_trees for log in logs], [log.evaluation.accuracy for log in logs])
plt.xlabel("Number of trees")
plt.ylabel("Accuracy (out-of-bag)")
plt.subplot(1, 2, 2)
plt.plot([log.num_trees for log in logs], [log.evaluation.loss for log in logs])
plt.xlabel("Number of trees")
plt.ylabel("Logloss (out-of-bag)")
plt.show()

# %% [markdown]
# Calculate the score of our hold-out validation dataset

# %%
predictions = model.predict(val_ds)
y_true      = validation_data["label"]

from sklearn.metrics import roc_auc_score
ROC_AUC = roc_auc_score(y_true, predictions)
print("The ROC AUC score is %.5f" % ROC_AUC )
# Out:
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 64ms/step
# The ROC AUC score is 0.99803

# %%
# Compute binary classification metrics with sklearn
import numpy as np
from sklearn.metrics import (
    accuracy_score,
    precision_score,
    recall_score,
    f1_score,
    roc_auc_score,
    average_precision_score,
    confusion_matrix,
    classification_report,
    matthews_corrcoef,
    log_loss,
    brier_score_loss,
)

# Get predictions (probabilities or class labels)
preds = model.predict(test_ds)
# If model outputs probabilities, convert to labels by threshold 0.5
if preds.ndim == 2:
    # For TFDF classification, preds may be class probabilities with shape (N, 2)
    if preds.shape[1] == 2:
        pos_probs = preds[:, 1]
    else:
        # If single-probability column (positive class)
        pos_probs = preds[:, -1]
    y_pred = (pos_probs >= 0.5).astype(int)
else:
    # Already class labels
    y_pred = preds.astype(int)
    pos_probs = None

# Ground truth labels (must be 0/1 integers)
y_true = test_data["label"].astype(int).to_numpy()

# Core metrics
metrics = {}
metrics["accuracy"] = accuracy_score(y_true, y_pred)
metrics["precision"] = precision_score(y_true, y_pred, zero_division=0)
metrics["recall"] = recall_score(y_true, y_pred, zero_division=0)
metrics["f1"] = f1_score(y_true, y_pred, zero_division=0)
metrics["mcc"] = matthews_corrcoef(y_true, y_pred)

# Probabilistic metrics (only if we have probabilities)
if pos_probs is not None:
    metrics["roc_auc"] = roc_auc_score(y_true, pos_probs)
    metrics["pr_auc"] = average_precision_score(y_true, pos_probs)
    metrics["log_loss"] = log_loss(y_true, pos_probs, labels=[0,1])
    metrics["brier_score"] = brier_score_loss(y_true, pos_probs)

# Confusion matrix and detailed report
cm = confusion_matrix(y_true, y_pred, labels=[0,1])
report = classification_report(y_true, y_pred, digits=4)

print("Sklearn binary metrics:")
for k, v in metrics.items():
    print(f"{k}: {v:.4f}")
print("\nConfusion matrix:\n", cm)
print("\nClassification report:\n", report)
# Out:
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 77ms/step
# Sklearn binary metrics:
# accuracy: 0.9884
# precision: 0.8871
# recall: 0.9322
# f1: 0.9091
# mcc: 0.9032
# roc_auc: 0.9961
# pr_auc: 0.9759
# log_loss: 0.0538
# brier_score: 0.0092
#
# Confusion matrix:
#  [[880   7]
#  [  4  55]]
#
# Classification report:
#                precision    recall  f1-score   support
#
#            0     0.9955    0.9921    0.9938       887
#            1     0.8871    0.9322    0.9091        59
#
#     accuracy                         0.9884       946
#    macro avg     0.9413    0.9622    0.9514       946
# weighted avg     0.9887    0.9884    0.9885       946
