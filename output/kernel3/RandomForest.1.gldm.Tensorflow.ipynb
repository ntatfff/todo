# %%
# Import packages and modules
import numpy  as np
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow_decision_forests as tfdf

from sklearn.model_selection import train_test_split
# Out:
# 2026-08-15 05:10:16.670294: I tensorflow/core/util/port.cc:113] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2026-08-15 05:10:17.012682: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2026-08-15 05:10:21.634045: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
# Check the version of TensorFlow Decision Forests
print("Found TensorFlow Decision Forests v" + tfdf.__version__)
# Out:
# Found TensorFlow Decision Forests v1.9.1

# %%
datasetPath = 'dataset/firstorder/kernel5/dataset.csv'

# %%
# Parameters
datasetPath = "dataset/gldm/kernel3/1.dataset.csv"

# %%
# train/validation/test = 70/10/20
dataset = pd.read_csv(datasetPath)

train_data, temp_data = train_test_split(dataset, test_size=0.3, random_state=42)
validation_data, test_data = train_test_split(temp_data, test_size=2/3, random_state=42)

# %%
from sklearn.utils.class_weight import compute_class_weight

# tinh class weight tren tap train
classes = np.array([0, 1])
weights = compute_class_weight(class_weight="balanced", classes=classes, y=train_data["label"])
class_weight = {0: weights[0], 1: weights[1]}

# gan sample_weight cho tung dong
train_data["sample_weight"] = train_data["label"].map(class_weight)
validation_data["sample_weight"] = validation_data["label"].map(class_weight)
test_data["sample_weight"] = test_data["label"].map(class_weight)

# Convert the dataset into a TensorFlow dataset.
train_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    train_data, label="label", weight="sample_weight"
)         
val_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    validation_data, label="label", weight="sample_weight"
)
test_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    test_data, label="label", weight="sample_weight"
)
# Out:
# 2026-08-15 05:10:35.445379: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:984] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2026-08-15 05:10:35.447180: W tensorflow/core/common_runtime/gpu/gpu_device.cc:2251] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...

# %%
import keras

# %%
# %%time

# Train a Random Forest model.
model = tfdf.keras.RandomForestModel()

# Add evaluation metrics
model.compile(
    metrics=["accuracy"]
)
model.fit(x=train_ds)

# # Train a Gradient Boosted Trees model.
# model = tfdf.keras.GradientBoostedTreesModel(num_trees=1500)
# model.fit(train_ds)
# Out:
# Use /tmp/tmpsi567wmg as temporary training directory
# Reading training dataset...
# Training dataset read in 0:00:02.582960. Found 3308 examples.
# Training model...
# Model trained in 0:00:00.111301
# Compiling model...
# [INFO 26-08-15 05:10:38.2993 UTC kernel.cc:1233] Loading model from path /tmp/tmpsi567wmg/model/ with prefix 8f554b85f3b04535
# [INFO 26-08-15 05:10:38.3156 UTC decision_forest.cc:734] Model loaded with 300 root(s), 12858 node(s), and 14 input feature(s).
# [INFO 26-08-15 05:10:38.3156 UTC abstract_model.cc:1362] Engine "RandomForestOptPred" built
# [INFO 26-08-15 05:10:38.3157 UTC kernel.cc:1061] Use fast generic engine
# Model compiled.
# CPU times: user 5.92 s, sys: 152 ms, total: 6.07 s
# Wall time: 5.82 s

# %%
# Evaluate the model
evaluate = model.evaluate(val_ds, return_dict=True)
print()

for name, value in evaluate.items():
    print(f"{name}: {value:.4f}")
# Out:
# WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 1/1 [==============================] - ETA: 0s - loss: 0.0000e+00 - accuracy: 0.9873
# 1/1 [==============================] - 3s 3s/step - loss: 0.0000e+00 - accuracy: 0.9873
# loss: 0.0000
# accuracy: 0.9873

# %%
# Model Summary
model.summary()
# Out:
# Model: "random_forest_model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
# =================================================================
# Total params: 1 (1.00 Byte)
# Trainable params: 0 (0.00 Byte)
# Non-trainable params: 1 (1.00 Byte)
# _________________________________________________________________
# Type: "RANDOM_FOREST"
# Task: CLASSIFICATION
# Label: "__LABEL"
#
# Input Features (14):
# 	DependenceEntropy
# 	DependenceNonUniformity
# 	DependenceNonUniformityNormalized
# 	DependenceVariance
# 	GrayLevelNonUniformity
# 	GrayLevelVariance
# 	HighGrayLevelEmphasis
# 	LargeDependenceEmphasis
# 	LargeDependenceHighGrayLevelEmphasis
# 	LargeDependenceLowGrayLevelEmphasis
# 	LowGrayLevelEmphasis
# 	SmallDependenceEmphasis
# 	SmallDependenceHighGrayLevelEmphasis
# 	SmallDependenceLowGrayLevelEmphasis
#
# Trained with weights
#
# Variable Importance: INV_MEAN_MIN_DEPTH:
#     1.                "HighGrayLevelEmphasis"  0.294321 ################
#     2. "SmallDependenceHighGrayLevelEmphasis"  0.264982 ############
#     3.                 "LowGrayLevelEmphasis"  0.231529 ########
#     4.                    "DependenceEntropy"  0.207333 #####
#     5.  "SmallDependenceLowGrayLevelEmphasis"  0.200797 ####
#     6.               "GrayLevelNonUniformity"  0.200456 ####
#     7.  "LargeDependenceLowGrayLevelEmphasis"  0.199212 ####
#     8. "LargeDependenceHighGrayLevelEmphasis"  0.177577 #
#     9.                    "GrayLevelVariance"  0.174530 #
#    10.              "DependenceNonUniformity"  0.165243
#    11.              "SmallDependenceEmphasis"  0.164158
#    12.    "DependenceNonUniformityNormalized"  0.163665
#    13.              "LargeDependenceEmphasis"  0.162171
#    14.                   "DependenceVariance"  0.161377
#
# Variable Importance: NUM_AS_ROOT:
#     1.                "HighGrayLevelEmphasis" 83.000000 ################
#     2. "SmallDependenceHighGrayLevelEmphasis" 78.000000 ###############
#     3.                 "LowGrayLevelEmphasis" 48.000000 #########
#     4.  "LargeDependenceLowGrayLevelEmphasis" 44.000000 ########
#     5.  "SmallDependenceLowGrayLevelEmphasis" 22.000000 ####
#     6. "LargeDependenceHighGrayLevelEmphasis" 13.000000 ##
#     7.               "GrayLevelNonUniformity" 10.000000 #
#     8.                    "DependenceEntropy"  1.000000
#     9.    "DependenceNonUniformityNormalized"  1.000000
#
# Variable Importance: NUM_NODES:
#     1.                "HighGrayLevelEmphasis" 791.000000 ################
#     2.                    "DependenceEntropy" 728.000000 ##############
#     3.                 "LowGrayLevelEmphasis" 692.000000 #############
#     4. "SmallDependenceHighGrayLevelEmphasis" 614.000000 ###########
#     5.               "GrayLevelNonUniformity" 541.000000 #########
#     6.  "SmallDependenceLowGrayLevelEmphasis" 515.000000 ########
#     7.  "LargeDependenceLowGrayLevelEmphasis" 421.000000 #####
#     8.                    "GrayLevelVariance" 408.000000 #####
#     9.              "SmallDependenceEmphasis" 327.000000 ###
#    10. "LargeDependenceHighGrayLevelEmphasis" 322.000000 ###
#    11.              "DependenceNonUniformity" 251.000000 #
#    12.    "DependenceNonUniformityNormalized" 233.000000
#    13.                   "DependenceVariance" 228.000000
#    14.              "LargeDependenceEmphasis" 208.000000
#
# Variable Importance: SUM_SCORE:
#     1.                "HighGrayLevelEmphasis" 202822.684374 ################
#     2. "SmallDependenceHighGrayLevelEmphasis" 159764.185695 ############
#     3.                 "LowGrayLevelEmphasis" 101344.958744 #######
#     4.  "LargeDependenceLowGrayLevelEmphasis" 66401.404095 #####
#     5.               "GrayLevelNonUniformity" 35819.300400 ##
#     6.                    "DependenceEntropy" 32629.469208 ##
#     7.  "SmallDependenceLowGrayLevelEmphasis" 30794.654317 ##
#     8. "LargeDependenceHighGrayLevelEmphasis" 13477.383548
#     9.                    "GrayLevelVariance" 11152.455558
#    10.    "DependenceNonUniformityNormalized" 4579.984874
#    11.              "SmallDependenceEmphasis" 4553.235293
#    12.              "DependenceNonUniformity" 4522.888012
#    13.                   "DependenceVariance" 3275.538380
#    14.              "LargeDependenceEmphasis" 3241.726294
#
#
#
# Winner takes all: true
# Out-of-bag evaluation: accuracy:0.972913 logloss:0.0958564
# Number of trees: 300
# Total number of nodes: 12858
#
# Number of nodes by tree:
# Count: 300 Average: 42.86 StdDev: 5.76603
# Min: 27 Max: 61 Ignored: 0
# ----------------------------------------------
# [ 27, 28)  1   0.33%   0.33%
# [ 28, 30)  2   0.67%   1.00%
# [ 30, 32)  3   1.00%   2.00% #
# [ 32, 34) 11   3.67%   5.67% ###
# [ 34, 35)  0   0.00%   5.67%
# [ 35, 37) 18   6.00%  11.67% ####
# [ 37, 39) 36  12.00%  23.67% ########
# [ 39, 41) 25   8.33%  32.00% ######
# [ 41, 42) 33  11.00%  43.00% ########
# [ 42, 44) 39  13.00%  56.00% #########
# [ 44, 46) 40  13.33%  69.33% #########
# [ 46, 48) 43  14.33%  83.67% ##########
# [ 48, 49)  0   0.00%  83.67%
# [ 49, 51) 16   5.33%  89.00% ####
# [ 51, 53) 15   5.00%  94.00% ###
# [ 53, 55) 10   3.33%  97.33% ##
# [ 55, 56)  5   1.67%  99.00% #
# [ 56, 58)  2   0.67%  99.67%
# [ 58, 60)  0   0.00%  99.67%
# [ 60, 61]  1   0.33% 100.00%
#
# Depth by leafs:
# Count: 6579 Average: 5.49126 StdDev: 1.91728
# Min: 2 Max: 13 Ignored: 0
# ----------------------------------------------
# [  2,  3)  260   3.95%   3.95% ##
# [  3,  4)  728  11.07%  15.02% #####
# [  4,  5) 1163  17.68%  32.69% ########
# [  5,  6) 1403  21.33%  54.02% ##########
# [  6,  7) 1134  17.24%  71.26% ########
# [  7,  8)  894  13.59%  84.85% ######
# [  8,  9)  522   7.93%  92.78% ####
# [  9, 10)  300   4.56%  97.34% ##
# [ 10, 11)  118   1.79%  99.13% #
# [ 11, 12)   48   0.73%  99.86%
# [ 12, 13)    7   0.11%  99.97%
# [ 13, 13]    2   0.03% 100.00%
#
# Number of training obs by leaf:
# Count: 6579 Average: 150.844 StdDev: 516.195
# Min: 5 Max: 2892 Ignored: 0
# ----------------------------------------------
# [    5,  149) 5879  89.36%  89.36% ##########
# [  149,  293)  241   3.66%  93.02%
# [  293,  438)   93   1.41%  94.44%
# [  438,  582)   36   0.55%  94.98%
# [  582,  727)   24   0.36%  95.35%
# [  727,  871)    6   0.09%  95.44%
# [  871, 1015)    0   0.00%  95.44%
# [ 1015, 1160)    0   0.00%  95.44%
# [ 1160, 1304)    0   0.00%  95.44%
# [ 1304, 1449)    0   0.00%  95.44%
# [ 1449, 1593)    0   0.00%  95.44%
# [ 1593, 1737)    1   0.02%  95.46%
# [ 1737, 1882)    7   0.11%  95.56%
# [ 1882, 2026)   15   0.23%  95.79%
# [ 2026, 2171)   20   0.30%  96.09%
# [ 2171, 2315)   20   0.30%  96.40%
# [ 2315, 2459)   48   0.73%  97.13%
# [ 2459, 2604)   83   1.26%  98.39%
# [ 2604, 2748)   89   1.35%  99.74%
# [ 2748, 2892]   17   0.26% 100.00%
#
# Attribute in nodes:
# 	791 : HighGrayLevelEmphasis [NUMERICAL]
# 	728 : DependenceEntropy [NUMERICAL]
# 	692 : LowGrayLevelEmphasis [NUMERICAL]
# 	614 : SmallDependenceHighGrayLevelEmphasis [NUMERICAL]
# 	541 : GrayLevelNonUniformity [NUMERICAL]
# 	515 : SmallDependenceLowGrayLevelEmphasis [NUMERICAL]
# 	421 : LargeDependenceLowGrayLevelEmphasis [NUMERICAL]
# 	408 : GrayLevelVariance [NUMERICAL]
# 	327 : SmallDependenceEmphasis [NUMERICAL]
# 	322 : LargeDependenceHighGrayLevelEmphasis [NUMERICAL]
# 	251 : DependenceNonUniformity [NUMERICAL]
# 	233 : DependenceNonUniformityNormalized [NUMERICAL]
# 	228 : DependenceVariance [NUMERICAL]
# 	208 : LargeDependenceEmphasis [NUMERICAL]
#
# Attribute in nodes with depth <= 0:
# 	83 : HighGrayLevelEmphasis [NUMERICAL]
# 	78 : SmallDependenceHighGrayLevelEmphasis [NUMERICAL]
# 	48 : LowGrayLevelEmphasis [NUMERICAL]
# 	44 : LargeDependenceLowGrayLevelEmphasis [NUMERICAL]
# 	22 : SmallDependenceLowGrayLevelEmphasis [NUMERICAL]
# 	13 : LargeDependenceHighGrayLevelEmphasis [NUMERICAL]
# 	10 : GrayLevelNonUniformity [NUMERICAL]
# 	1 : DependenceNonUniformityNormalized [NUMERICAL]
# 	1 : DependenceEntropy [NUMERICAL]
#
# Attribute in nodes with depth <= 1:
# 	250 : HighGrayLevelEmphasis [NUMERICAL]
# 	180 : SmallDependenceHighGrayLevelEmphasis [NUMERICAL]
# 	136 : LowGrayLevelEmphasis [NUMERICAL]
# 	73 : LargeDependenceLowGrayLevelEmphasis [NUMERICAL]
# 	69 : GrayLevelNonUniformity [NUMERICAL]
# 	63 : SmallDependenceLowGrayLevelEmphasis [NUMERICAL]
# 	46 : LargeDependenceHighGrayLevelEmphasis [NUMERICAL]
# 	43 : DependenceEntropy [NUMERICAL]
# 	11 : DependenceNonUniformity [NUMERICAL]
# 	9 : DependenceNonUniformityNormalized [NUMERICAL]
# 	8 : GrayLevelVariance [NUMERICAL]
# 	6 : LargeDependenceEmphasis [NUMERICAL]
# 	5 : SmallDependenceEmphasis [NUMERICAL]
# 	1 : DependenceVariance [NUMERICAL]
#
# Attribute in nodes with depth <= 2:
# 	424 : HighGrayLevelEmphasis [NUMERICAL]
# 	265 : SmallDependenceHighGrayLevelEmphasis [NUMERICAL]
# 	261 : LowGrayLevelEmphasis [NUMERICAL]
# 	182 : DependenceEntropy [NUMERICAL]
# 	163 : GrayLevelNonUniformity [NUMERICAL]
# 	149 : SmallDependenceLowGrayLevelEmphasis [NUMERICAL]
# 	113 : LargeDependenceLowGrayLevelEmphasis [NUMERICAL]
# 	95 : LargeDependenceHighGrayLevelEmphasis [NUMERICAL]
# 	75 : GrayLevelVariance [NUMERICAL]
# 	30 : SmallDependenceEmphasis [NUMERICAL]
# 	25 : DependenceVariance [NUMERICAL]
# 	25 : DependenceNonUniformityNormalized [NUMERICAL]
# 	21 : DependenceNonUniformity [NUMERICAL]
# 	12 : LargeDependenceEmphasis [NUMERICAL]
#
# Attribute in nodes with depth <= 3:
# 	546 : HighGrayLevelEmphasis [NUMERICAL]
# 	395 : LowGrayLevelEmphasis [NUMERICAL]
# 	363 : SmallDependenceHighGrayLevelEmphasis [NUMERICAL]
# 	355 : DependenceEntropy [NUMERICAL]
# 	267 : GrayLevelNonUniformity [NUMERICAL]
# 	262 : SmallDependenceLowGrayLevelEmphasis [NUMERICAL]
# 	183 : LargeDependenceLowGrayLevelEmphasis [NUMERICAL]
# 	171 : GrayLevelVariance [NUMERICAL]
# 	144 : LargeDependenceHighGrayLevelEmphasis [NUMERICAL]
# 	73 : SmallDependenceEmphasis [NUMERICAL]
# 	65 : DependenceNonUniformity [NUMERICAL]
# 	59 : DependenceVariance [NUMERICAL]
# 	55 : LargeDependenceEmphasis [NUMERICAL]
# 	54 : DependenceNonUniformityNormalized [NUMERICAL]
#
# Attribute in nodes with depth <= 5:
# 	694 : HighGrayLevelEmphasis [NUMERICAL]
# 	613 : DependenceEntropy [NUMERICAL]
# 	590 : LowGrayLevelEmphasis [NUMERICAL]
# 	501 : SmallDependenceHighGrayLevelEmphasis [NUMERICAL]
# 	440 : SmallDependenceLowGrayLevelEmphasis [NUMERICAL]
# 	438 : GrayLevelNonUniformity [NUMERICAL]
# 	333 : LargeDependenceLowGrayLevelEmphasis [NUMERICAL]
# 	325 : GrayLevelVariance [NUMERICAL]
# 	258 : LargeDependenceHighGrayLevelEmphasis [NUMERICAL]
# 	215 : SmallDependenceEmphasis [NUMERICAL]
# 	165 : DependenceNonUniformity [NUMERICAL]
# 	158 : DependenceVariance [NUMERICAL]
# 	154 : DependenceNonUniformityNormalized [NUMERICAL]
# 	128 : LargeDependenceEmphasis [NUMERICAL]
#
# Condition type in nodes:
# 	6279 : HigherCondition
# Condition type in nodes with depth <= 0:
# 	300 : HigherCondition
# Condition type in nodes with depth <= 1:
# 	900 : HigherCondition
# Condition type in nodes with depth <= 2:
# 	1840 : HigherCondition
# Condition type in nodes with depth <= 3:
# 	2992 : HigherCondition
# Condition type in nodes with depth <= 5:
# 	5012 : HigherCondition
# Node format: NOT_SET
#
# Training OOB:
# 	trees: 1, Out-of-bag evaluation: accuracy:0.965575 logloss:1.2408
# 	trees: 11, Out-of-bag evaluation: accuracy:0.957906 logloss:0.711761
# 	trees: 21, Out-of-bag evaluation: accuracy:0.96009 logloss:0.500883
# 	trees: 31, Out-of-bag evaluation: accuracy:0.958049 logloss:0.248589
# 	trees: 41, Out-of-bag evaluation: accuracy:0.955841 logloss:0.250734
# 	trees: 51, Out-of-bag evaluation: accuracy:0.963111 logloss:0.173097
# 	trees: 61, Out-of-bag evaluation: accuracy:0.963596 logloss:0.176532
# 	trees: 71, Out-of-bag evaluation: accuracy:0.963273 logloss:0.0995918
# 	trees: 81, Out-of-bag evaluation: accuracy:0.963434 logloss:0.0974035
# 	trees: 91, Out-of-bag evaluation: accuracy:0.963434 logloss:0.0996801
# 	trees: 101, Out-of-bag evaluation: accuracy:0.963434 logloss:0.098133
# 	trees: 112, Out-of-bag evaluation: accuracy:0.965804 logloss:0.0964823
# 	trees: 122, Out-of-bag evaluation: accuracy:0.965804 logloss:0.0962359
# 	trees: 132, Out-of-bag evaluation: accuracy:0.960903 logloss:0.0966002
# 	trees: 142, Out-of-bag evaluation: accuracy:0.965643 logloss:0.0968993
# 	trees: 152, Out-of-bag evaluation: accuracy:0.965643 logloss:0.0972774
# 	trees: 162, Out-of-bag evaluation: accuracy:0.968012 logloss:0.0971329
# 	trees: 172, Out-of-bag evaluation: accuracy:0.970382 logloss:0.096972
# 	trees: 182, Out-of-bag evaluation: accuracy:0.970543 logloss:0.0974124
# 	trees: 192, Out-of-bag evaluation: accuracy:0.970543 logloss:0.0974837
# 	trees: 202, Out-of-bag evaluation: accuracy:0.970543 logloss:0.0977985
# 	trees: 212, Out-of-bag evaluation: accuracy:0.970543 logloss:0.0983703
# 	trees: 222, Out-of-bag evaluation: accuracy:0.970543 logloss:0.0989107
# 	trees: 232, Out-of-bag evaluation: accuracy:0.972913 logloss:0.0971076
# 	trees: 242, Out-of-bag evaluation: accuracy:0.972913 logloss:0.0971976
# 	trees: 252, Out-of-bag evaluation: accuracy:0.972751 logloss:0.0975411
# 	trees: 262, Out-of-bag evaluation: accuracy:0.972751 logloss:0.0978304
# 	trees: 272, Out-of-bag evaluation: accuracy:0.972913 logloss:0.0970451
# 	trees: 282, Out-of-bag evaluation: accuracy:0.972751 logloss:0.0955407
# 	trees: 292, Out-of-bag evaluation: accuracy:0.972751 logloss:0.095911
# 	trees: 300, Out-of-bag evaluation: accuracy:0.972913 logloss:0.0958564

# %%
# Model features
model.make_inspector().features()
# Out:
# ["DependenceEntropy" (1; #0),
#  "DependenceNonUniformity" (1; #1),
#  "DependenceNonUniformityNormalized" (1; #2),
#  "DependenceVariance" (1; #3),
#  "GrayLevelNonUniformity" (1; #4),
#  "GrayLevelVariance" (1; #5),
#  "HighGrayLevelEmphasis" (1; #6),
#  "LargeDependenceEmphasis" (1; #7),
#  "LargeDependenceHighGrayLevelEmphasis" (1; #8),
#  "LargeDependenceLowGrayLevelEmphasis" (1; #9),
#  "LowGrayLevelEmphasis" (1; #10),
#  "SmallDependenceEmphasis" (1; #11),
#  "SmallDependenceHighGrayLevelEmphasis" (1; #12),
#  "SmallDependenceLowGrayLevelEmphasis" (1; #13)]

# %%
# Feature importance
model.make_inspector().variable_importances()
# Out:
# {'INV_MEAN_MIN_DEPTH': [("HighGrayLevelEmphasis" (1; #6), 0.2943208748429715),
#   ("SmallDependenceHighGrayLevelEmphasis" (1; #12), 0.26498211801685106),
#   ("LowGrayLevelEmphasis" (1; #10), 0.23152860625621655),
#   ("DependenceEntropy" (1; #0), 0.20733256422859728),
#   ("SmallDependenceLowGrayLevelEmphasis" (1; #13), 0.20079705470486992),
#   ("GrayLevelNonUniformity" (1; #4), 0.2004563162040792),
#   ("LargeDependenceLowGrayLevelEmphasis" (1; #9), 0.19921213960129028),
#   ("LargeDependenceHighGrayLevelEmphasis" (1; #8), 0.17757686609139872),
#   ("GrayLevelVariance" (1; #5), 0.17453021550531567),
#   ("DependenceNonUniformity" (1; #1), 0.16524314035973303),
#   ("SmallDependenceEmphasis" (1; #11), 0.16415786790897977),
#   ("DependenceNonUniformityNormalized" (1; #2), 0.1636649427300347),
#   ("LargeDependenceEmphasis" (1; #7), 0.16217063031188603),
#   ("DependenceVariance" (1; #3), 0.16137673366042224)],
#  'SUM_SCORE': [("HighGrayLevelEmphasis" (1; #6), 202822.6843743077),
#   ("SmallDependenceHighGrayLevelEmphasis" (1; #12), 159764.18569537322),
#   ("LowGrayLevelEmphasis" (1; #10), 101344.95874408017),
#   ("LargeDependenceLowGrayLevelEmphasis" (1; #9), 66401.40409534046),
#   ("GrayLevelNonUniformity" (1; #4), 35819.30039954697),
#   ("DependenceEntropy" (1; #0), 32629.46920797864),
#   ("SmallDependenceLowGrayLevelEmphasis" (1; #13), 30794.65431715317),
#   ("LargeDependenceHighGrayLevelEmphasis" (1; #8), 13477.383548407553),
#   ("GrayLevelVariance" (1; #5), 11152.455557706357),
#   ("DependenceNonUniformityNormalized" (1; #2), 4579.984873593845),
#   ("SmallDependenceEmphasis" (1; #11), 4553.2352928639475),
#   ("DependenceNonUniformity" (1; #1), 4522.888011575706),
#   ("DependenceVariance" (1; #3), 3275.538380225903),
#   ("LargeDependenceEmphasis" (1; #7), 3241.726293882449)],
#  'NUM_AS_ROOT': [("HighGrayLevelEmphasis" (1; #6), 83.0),
#   ("SmallDependenceHighGrayLevelEmphasis" (1; #12), 78.0),
#   ("LowGrayLevelEmphasis" (1; #10), 48.0),
#   ("LargeDependenceLowGrayLevelEmphasis" (1; #9), 44.0),
#   ("SmallDependenceLowGrayLevelEmphasis" (1; #13), 22.0),
#   ("LargeDependenceHighGrayLevelEmphasis" (1; #8), 13.0),
#   ("GrayLevelNonUniformity" (1; #4), 10.0),
#   ("DependenceEntropy" (1; #0), 1.0),
#   ("DependenceNonUniformityNormalized" (1; #2), 1.0)],
#  'NUM_NODES': [("HighGrayLevelEmphasis" (1; #6), 791.0),
#   ("DependenceEntropy" (1; #0), 728.0),
#   ("LowGrayLevelEmphasis" (1; #10), 692.0),
#   ("SmallDependenceHighGrayLevelEmphasis" (1; #12), 614.0),
#   ("GrayLevelNonUniformity" (1; #4), 541.0),
#   ("SmallDependenceLowGrayLevelEmphasis" (1; #13), 515.0),
#   ("LargeDependenceLowGrayLevelEmphasis" (1; #9), 421.0),
#   ("GrayLevelVariance" (1; #5), 408.0),
#   ("SmallDependenceEmphasis" (1; #11), 327.0),
#   ("LargeDependenceHighGrayLevelEmphasis" (1; #8), 322.0),
#   ("DependenceNonUniformity" (1; #1), 251.0),
#   ("DependenceNonUniformityNormalized" (1; #2), 233.0),
#   ("DependenceVariance" (1; #3), 228.0),
#   ("LargeDependenceEmphasis" (1; #7), 208.0)]}

# %%
# Model self evaluation
model.make_inspector().evaluation()
# Out:
# Evaluation(num_examples=3308, accuracy=0.9729129403535716, loss=0.09585640300245912, rmse=None, ndcg=None, aucs=None, auuc=None, qini=None)

# %%
logs = model.make_inspector().training_logs()

plt.figure(figsize=(12, 4))
plt.subplot(1, 2, 1)
plt.plot([log.num_trees for log in logs], [log.evaluation.accuracy for log in logs])
plt.xlabel("Number of trees")
plt.ylabel("Accuracy (out-of-bag)")
plt.subplot(1, 2, 2)
plt.plot([log.num_trees for log in logs], [log.evaluation.loss for log in logs])
plt.xlabel("Number of trees")
plt.ylabel("Logloss (out-of-bag)")
plt.show()

# %% [markdown]
# Calculate the score of our hold-out validation dataset

# %%
predictions = model.predict(val_ds)
y_true      = validation_data["label"]

from sklearn.metrics import roc_auc_score
ROC_AUC = roc_auc_score(y_true, predictions)
print("The ROC AUC score is %.5f" % ROC_AUC )
# Out:
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 60ms/step
# The ROC AUC score is 0.99558

# %%
# Compute binary classification metrics with sklearn
import numpy as np
from sklearn.metrics import (
    accuracy_score,
    precision_score,
    recall_score,
    f1_score,
    roc_auc_score,
    average_precision_score,
    confusion_matrix,
    classification_report,
    matthews_corrcoef,
    log_loss,
    brier_score_loss,
)

# Get predictions (probabilities or class labels)
preds = model.predict(test_ds)
# If model outputs probabilities, convert to labels by threshold 0.5
if preds.ndim == 2:
    # For TFDF classification, preds may be class probabilities with shape (N, 2)
    if preds.shape[1] == 2:
        pos_probs = preds[:, 1]
    else:
        # If single-probability column (positive class)
        pos_probs = preds[:, -1]
    y_pred = (pos_probs >= 0.5).astype(int)
else:
    # Already class labels
    y_pred = preds.astype(int)
    pos_probs = None

# Ground truth labels (must be 0/1 integers)
y_true = test_data["label"].astype(int).to_numpy()

# Core metrics
metrics = {}
metrics["accuracy"] = accuracy_score(y_true, y_pred)
metrics["precision"] = precision_score(y_true, y_pred, zero_division=0)
metrics["recall"] = recall_score(y_true, y_pred, zero_division=0)
metrics["f1"] = f1_score(y_true, y_pred, zero_division=0)
metrics["mcc"] = matthews_corrcoef(y_true, y_pred)

# Probabilistic metrics (only if we have probabilities)
if pos_probs is not None:
    metrics["roc_auc"] = roc_auc_score(y_true, pos_probs)
    metrics["pr_auc"] = average_precision_score(y_true, pos_probs)
    metrics["log_loss"] = log_loss(y_true, pos_probs, labels=[0,1])
    metrics["brier_score"] = brier_score_loss(y_true, pos_probs)

# Confusion matrix and detailed report
cm = confusion_matrix(y_true, y_pred, labels=[0,1])
report = classification_report(y_true, y_pred, digits=4)

print("Sklearn binary metrics:")
for k, v in metrics.items():
    print(f"{k}: {v:.4f}")
print("\nConfusion matrix:\n", cm)
print("\nClassification report:\n", report)
# Out:
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 73ms/step
# Sklearn binary metrics:
# accuracy: 0.9915
# precision: 0.8800
# recall: 0.9565
# f1: 0.9167
# mcc: 0.9131
# roc_auc: 0.9950
# pr_auc: 0.9669
# log_loss: 0.0308
# brier_score: 0.0079
#
# Confusion matrix:
#  [[894   6]
#  [  2  44]]
#
# Classification report:
#                precision    recall  f1-score   support
#
#            0     0.9978    0.9933    0.9955       900
#            1     0.8800    0.9565    0.9167        46
#
#     accuracy                         0.9915       946
#    macro avg     0.9389    0.9749    0.9561       946
# weighted avg     0.9920    0.9915    0.9917       946
