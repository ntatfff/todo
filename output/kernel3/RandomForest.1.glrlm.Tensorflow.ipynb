# %%
# Import packages and modules
import numpy  as np
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow_decision_forests as tfdf

from sklearn.model_selection import train_test_split
# Out:
# 2026-08-15 05:10:52.462184: I tensorflow/core/util/port.cc:113] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2026-08-15 05:10:52.850929: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2026-08-15 05:10:58.212580: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
# Check the version of TensorFlow Decision Forests
print("Found TensorFlow Decision Forests v" + tfdf.__version__)
# Out:
# Found TensorFlow Decision Forests v1.9.1

# %%
datasetPath = 'dataset/firstorder/kernel5/dataset.csv'

# %%
# Parameters
datasetPath = "dataset/glrlm/kernel3/1.dataset.csv"

# %%
# train/validation/test = 70/10/20
dataset = pd.read_csv(datasetPath)

train_data, temp_data = train_test_split(dataset, test_size=0.3, random_state=42)
validation_data, test_data = train_test_split(temp_data, test_size=2/3, random_state=42)

# %%
from sklearn.utils.class_weight import compute_class_weight

# tinh class weight tren tap train
classes = np.array([0, 1])
weights = compute_class_weight(class_weight="balanced", classes=classes, y=train_data["label"])
class_weight = {0: weights[0], 1: weights[1]}

# gan sample_weight cho tung dong
train_data["sample_weight"] = train_data["label"].map(class_weight)
validation_data["sample_weight"] = validation_data["label"].map(class_weight)
test_data["sample_weight"] = test_data["label"].map(class_weight)

# Convert the dataset into a TensorFlow dataset.
train_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    train_data, label="label", weight="sample_weight"
)         
val_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    validation_data, label="label", weight="sample_weight"
)
test_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    test_data, label="label", weight="sample_weight"
)
# Out:
# 2026-08-15 05:11:11.267613: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:984] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2026-08-15 05:11:11.269230: W tensorflow/core/common_runtime/gpu/gpu_device.cc:2251] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...

# %%
import keras

# %%
# %%time

# Train a Random Forest model.
model = tfdf.keras.RandomForestModel()

# Add evaluation metrics
model.compile(
    metrics=["accuracy"]
)
model.fit(x=train_ds)

# # Train a Gradient Boosted Trees model.
# model = tfdf.keras.GradientBoostedTreesModel(num_trees=1500)
# model.fit(train_ds)
# Out:
# Use /tmp/tmp861x6qwa as temporary training directory
# Reading training dataset...
# Training dataset read in 0:00:02.590538. Found 3308 examples.
# Training model...
# Model trained in 0:00:00.110735
# Compiling model...
# [INFO 26-08-15 05:11:14.1244 UTC kernel.cc:1233] Loading model from path /tmp/tmp861x6qwa/model/ with prefix 1f67917e0098406f
# [INFO 26-08-15 05:11:14.1403 UTC decision_forest.cc:734] Model loaded with 300 root(s), 12476 node(s), and 16 input feature(s).
# [INFO 26-08-15 05:11:14.1403 UTC abstract_model.cc:1362] Engine "RandomForestOptPred" built
# [INFO 26-08-15 05:11:14.1403 UTC kernel.cc:1061] Use fast generic engine
# Model compiled.
# CPU times: user 5.9 s, sys: 143 ms, total: 6.04 s
# Wall time: 5.83 s

# %%
# Evaluate the model
evaluate = model.evaluate(val_ds, return_dict=True)
print()

for name, value in evaluate.items():
    print(f"{name}: {value:.4f}")
# Out:
# WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 1/1 [==============================] - ETA: 0s - loss: 0.0000e+00 - accuracy: 0.9894
# 1/1 [==============================] - 3s 3s/step - loss: 0.0000e+00 - accuracy: 0.9894
# loss: 0.0000
# accuracy: 0.9894

# %%
# Model Summary
model.summary()
# Out:
# Model: "random_forest_model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
# =================================================================
# Total params: 1 (1.00 Byte)
# Trainable params: 0 (0.00 Byte)
# Non-trainable params: 1 (1.00 Byte)
# _________________________________________________________________
# Type: "RANDOM_FOREST"
# Task: CLASSIFICATION
# Label: "__LABEL"
#
# Input Features (16):
# 	GrayLevelNonUniformity
# 	GrayLevelNonUniformityNormalized
# 	GrayLevelVariance
# 	HighGrayLevelRunEmphasis
# 	LongRunEmphasis
# 	LongRunHighGrayLevelEmphasis
# 	LongRunLowGrayLevelEmphasis
# 	LowGrayLevelRunEmphasis
# 	RunEntropy
# 	RunLengthNonUniformity
# 	RunLengthNonUniformityNormalized
# 	RunPercentage
# 	RunVariance
# 	ShortRunEmphasis
# 	ShortRunHighGrayLevelEmphasis
# 	ShortRunLowGrayLevelEmphasis
#
# Trained with weights
#
# Variable Importance: INV_MEAN_MIN_DEPTH:
#     1.    "ShortRunHighGrayLevelEmphasis"  0.252465 ################
#     2.         "HighGrayLevelRunEmphasis"  0.244672 ##############
#     3.     "LongRunHighGrayLevelEmphasis"  0.218282 #########
#     4. "GrayLevelNonUniformityNormalized"  0.204992 #######
#     5.      "LongRunLowGrayLevelEmphasis"  0.202330 ######
#     6.           "GrayLevelNonUniformity"  0.198936 #####
#     7.          "LowGrayLevelRunEmphasis"  0.193704 #####
#     8.                       "RunEntropy"  0.190284 ####
#     9.     "ShortRunLowGrayLevelEmphasis"  0.184256 ###
#    10.                "GrayLevelVariance"  0.172229 #
#    11.                  "LongRunEmphasis"  0.171389
#    12. "RunLengthNonUniformityNormalized"  0.169603
#    13.                    "RunPercentage"  0.169190
#    14.                      "RunVariance"  0.168570
#    15.           "RunLengthNonUniformity"  0.168349
#    16.                 "ShortRunEmphasis"  0.166857
#
# Variable Importance: NUM_AS_ROOT:
#     1.    "ShortRunHighGrayLevelEmphasis" 91.000000 ################
#     2.         "HighGrayLevelRunEmphasis" 76.000000 #############
#     3.     "LongRunHighGrayLevelEmphasis" 58.000000 ##########
#     4.      "LongRunLowGrayLevelEmphasis" 34.000000 #####
#     5.          "LowGrayLevelRunEmphasis" 21.000000 ###
#     6.     "ShortRunLowGrayLevelEmphasis" 11.000000 #
#     7.           "GrayLevelNonUniformity"  7.000000 #
#     8. "GrayLevelNonUniformityNormalized"  1.000000
#     9.                  "LongRunEmphasis"  1.000000
#
# Variable Importance: NUM_NODES:
#     1.    "ShortRunHighGrayLevelEmphasis" 573.000000 ################
#     2. "GrayLevelNonUniformityNormalized" 552.000000 ###############
#     3.         "HighGrayLevelRunEmphasis" 547.000000 ##############
#     4.           "GrayLevelNonUniformity" 532.000000 ##############
#     5.                       "RunEntropy" 489.000000 ############
#     6.          "LowGrayLevelRunEmphasis" 454.000000 ###########
#     7.      "LongRunLowGrayLevelEmphasis" 453.000000 ###########
#     8.     "LongRunHighGrayLevelEmphasis" 428.000000 #########
#     9.     "ShortRunLowGrayLevelEmphasis" 397.000000 ########
#    10.                "GrayLevelVariance" 288.000000 ####
#    11.                  "LongRunEmphasis" 248.000000 ##
#    12.                 "ShortRunEmphasis" 247.000000 ##
#    13. "RunLengthNonUniformityNormalized" 241.000000 ##
#    14.                      "RunVariance" 235.000000 #
#    15.           "RunLengthNonUniformity" 216.000000 #
#    16.                    "RunPercentage" 188.000000
#
# Variable Importance: SUM_SCORE:
#     1.    "ShortRunHighGrayLevelEmphasis" 168119.538732 ################
#     2.         "HighGrayLevelRunEmphasis" 146185.925276 #############
#     3.     "LongRunHighGrayLevelEmphasis" 99900.436101 #########
#     4.      "LongRunLowGrayLevelEmphasis" 60114.076831 #####
#     5.          "LowGrayLevelRunEmphasis" 42979.625384 ###
#     6. "GrayLevelNonUniformityNormalized" 36008.448648 ###
#     7.     "ShortRunLowGrayLevelEmphasis" 30882.219476 ##
#     8.           "GrayLevelNonUniformity" 30488.283511 ##
#     9.                       "RunEntropy" 20979.417472 #
#    10.                "GrayLevelVariance" 7395.785876
#    11.                  "LongRunEmphasis" 6755.000495
#    12.                    "RunPercentage" 6327.264083
#    13. "RunLengthNonUniformityNormalized" 6013.895044
#    14.           "RunLengthNonUniformity" 5780.347982
#    15.                      "RunVariance" 5158.956348
#    16.                 "ShortRunEmphasis" 3236.821350
#
#
#
# Winner takes all: true
# Out-of-bag evaluation: accuracy:0.959491 logloss:0.26457
# Number of trees: 300
# Total number of nodes: 12476
#
# Number of nodes by tree:
# Count: 300 Average: 41.5867 StdDev: 5.37672
# Min: 19 Max: 59 Ignored: 0
# ----------------------------------------------
# [ 19, 21)  1   0.33%   0.33%
# [ 21, 23)  0   0.00%   0.33%
# [ 23, 25)  0   0.00%   0.33%
# [ 25, 27)  0   0.00%   0.33%
# [ 27, 29)  1   0.33%   0.67%
# [ 29, 31)  5   1.67%   2.33% #
# [ 31, 33)  4   1.33%   3.67% #
# [ 33, 35) 11   3.67%   7.33% ##
# [ 35, 37) 15   5.00%  12.33% ###
# [ 37, 39) 28   9.33%  21.67% #####
# [ 39, 41) 41  13.67%  35.33% #######
# [ 41, 43) 58  19.33%  54.67% ##########
# [ 43, 45) 49  16.33%  71.00% ########
# [ 45, 47) 35  11.67%  82.67% ######
# [ 47, 49) 23   7.67%  90.33% ####
# [ 49, 51) 13   4.33%  94.67% ##
# [ 51, 53)  6   2.00%  96.67% #
# [ 53, 55)  2   0.67%  97.33%
# [ 55, 57)  5   1.67%  99.00% #
# [ 57, 59]  3   1.00% 100.00% #
#
# Depth by leafs:
# Count: 6388 Average: 5.3588 StdDev: 1.82086
# Min: 1 Max: 13 Ignored: 0
# ----------------------------------------------
# [  1,  2)    1   0.02%   0.02%
# [  2,  3)  238   3.73%   3.74% ##
# [  3,  4)  742  11.62%  15.36% #####
# [  4,  5) 1232  19.29%  34.64% #########
# [  5,  6) 1392  21.79%  56.43% ##########
# [  6,  7) 1155  18.08%  74.51% ########
# [  7,  8)  799  12.51%  87.02% ######
# [  8,  9)  490   7.67%  94.69% ####
# [  9, 10)  242   3.79%  98.48% ##
# [ 10, 11)   61   0.95%  99.44%
# [ 11, 12)   26   0.41%  99.84%
# [ 12, 13)    6   0.09%  99.94%
# [ 13, 13]    4   0.06% 100.00%
#
# Number of training obs by leaf:
# Count: 6388 Average: 155.354 StdDev: 527.235
# Min: 5 Max: 2877 Ignored: 0
# ----------------------------------------------
# [    5,  148) 5667  88.71%  88.71% ##########
# [  148,  292)  277   4.34%  93.05%
# [  292,  435)  117   1.83%  94.88%
# [  435,  579)   26   0.41%  95.29%
# [  579,  723)    0   0.00%  95.29%
# [  723,  866)    1   0.02%  95.30%
# [  866, 1010)    0   0.00%  95.30%
# [ 1010, 1154)    0   0.00%  95.30%
# [ 1154, 1297)    0   0.00%  95.30%
# [ 1297, 1441)    0   0.00%  95.30%
# [ 1441, 1585)    0   0.00%  95.30%
# [ 1585, 1728)    0   0.00%  95.30%
# [ 1728, 1872)    0   0.00%  95.30%
# [ 1872, 2016)    0   0.00%  95.30%
# [ 2016, 2159)    3   0.05%  95.35%
# [ 2159, 2303)   22   0.34%  95.70%
# [ 2303, 2447)   83   1.30%  96.99%
# [ 2447, 2590)  114   1.78%  98.78%
# [ 2590, 2734)   58   0.91%  99.69%
# [ 2734, 2877]   20   0.31% 100.00%
#
# Attribute in nodes:
# 	573 : ShortRunHighGrayLevelEmphasis [NUMERICAL]
# 	552 : GrayLevelNonUniformityNormalized [NUMERICAL]
# 	547 : HighGrayLevelRunEmphasis [NUMERICAL]
# 	532 : GrayLevelNonUniformity [NUMERICAL]
# 	489 : RunEntropy [NUMERICAL]
# 	454 : LowGrayLevelRunEmphasis [NUMERICAL]
# 	453 : LongRunLowGrayLevelEmphasis [NUMERICAL]
# 	428 : LongRunHighGrayLevelEmphasis [NUMERICAL]
# 	397 : ShortRunLowGrayLevelEmphasis [NUMERICAL]
# 	288 : GrayLevelVariance [NUMERICAL]
# 	248 : LongRunEmphasis [NUMERICAL]
# 	247 : ShortRunEmphasis [NUMERICAL]
# 	241 : RunLengthNonUniformityNormalized [NUMERICAL]
# 	235 : RunVariance [NUMERICAL]
# 	216 : RunLengthNonUniformity [NUMERICAL]
# 	188 : RunPercentage [NUMERICAL]
#
# Attribute in nodes with depth <= 0:
# 	91 : ShortRunHighGrayLevelEmphasis [NUMERICAL]
# 	76 : HighGrayLevelRunEmphasis [NUMERICAL]
# 	58 : LongRunHighGrayLevelEmphasis [NUMERICAL]
# 	34 : LongRunLowGrayLevelEmphasis [NUMERICAL]
# 	21 : LowGrayLevelRunEmphasis [NUMERICAL]
# 	11 : ShortRunLowGrayLevelEmphasis [NUMERICAL]
# 	7 : GrayLevelNonUniformity [NUMERICAL]
# 	1 : LongRunEmphasis [NUMERICAL]
# 	1 : GrayLevelNonUniformityNormalized [NUMERICAL]
#
# Attribute in nodes with depth <= 1:
# 	179 : ShortRunHighGrayLevelEmphasis [NUMERICAL]
# 	174 : HighGrayLevelRunEmphasis [NUMERICAL]
# 	111 : LongRunHighGrayLevelEmphasis [NUMERICAL]
# 	91 : GrayLevelNonUniformityNormalized [NUMERICAL]
# 	81 : GrayLevelNonUniformity [NUMERICAL]
# 	63 : LongRunLowGrayLevelEmphasis [NUMERICAL]
# 	43 : LowGrayLevelRunEmphasis [NUMERICAL]
# 	34 : ShortRunLowGrayLevelEmphasis [NUMERICAL]
# 	31 : RunEntropy [NUMERICAL]
# 	21 : RunPercentage [NUMERICAL]
# 	20 : RunLengthNonUniformity [NUMERICAL]
# 	17 : LongRunEmphasis [NUMERICAL]
# 	16 : RunLengthNonUniformityNormalized [NUMERICAL]
# 	12 : RunVariance [NUMERICAL]
# 	3 : ShortRunEmphasis [NUMERICAL]
# 	3 : GrayLevelVariance [NUMERICAL]
#
# Attribute in nodes with depth <= 2:
# 	301 : ShortRunHighGrayLevelEmphasis [NUMERICAL]
# 	289 : HighGrayLevelRunEmphasis [NUMERICAL]
# 	181 : LongRunHighGrayLevelEmphasis [NUMERICAL]
# 	181 : GrayLevelNonUniformityNormalized [NUMERICAL]
# 	165 : GrayLevelNonUniformity [NUMERICAL]
# 	150 : LongRunLowGrayLevelEmphasis [NUMERICAL]
# 	130 : RunEntropy [NUMERICAL]
# 	124 : LowGrayLevelRunEmphasis [NUMERICAL]
# 	104 : ShortRunLowGrayLevelEmphasis [NUMERICAL]
# 	54 : GrayLevelVariance [NUMERICAL]
# 	37 : RunLengthNonUniformityNormalized [NUMERICAL]
# 	35 : RunPercentage [NUMERICAL]
# 	33 : LongRunEmphasis [NUMERICAL]
# 	32 : RunLengthNonUniformity [NUMERICAL]
# 	23 : RunVariance [NUMERICAL]
# 	20 : ShortRunEmphasis [NUMERICAL]
#
# Attribute in nodes with depth <= 3:
# 	379 : ShortRunHighGrayLevelEmphasis [NUMERICAL]
# 	375 : HighGrayLevelRunEmphasis [NUMERICAL]
# 	299 : GrayLevelNonUniformityNormalized [NUMERICAL]
# 	286 : GrayLevelNonUniformity [NUMERICAL]
# 	243 : RunEntropy [NUMERICAL]
# 	240 : LongRunHighGrayLevelEmphasis [NUMERICAL]
# 	234 : LongRunLowGrayLevelEmphasis [NUMERICAL]
# 	221 : LowGrayLevelRunEmphasis [NUMERICAL]
# 	192 : ShortRunLowGrayLevelEmphasis [NUMERICAL]
# 	126 : GrayLevelVariance [NUMERICAL]
# 	79 : LongRunEmphasis [NUMERICAL]
# 	77 : RunLengthNonUniformity [NUMERICAL]
# 	76 : RunLengthNonUniformityNormalized [NUMERICAL]
# 	71 : RunVariance [NUMERICAL]
# 	70 : RunPercentage [NUMERICAL]
# 	69 : ShortRunEmphasis [NUMERICAL]
#
# Attribute in nodes with depth <= 5:
# 	497 : ShortRunHighGrayLevelEmphasis [NUMERICAL]
# 	480 : HighGrayLevelRunEmphasis [NUMERICAL]
# 	465 : GrayLevelNonUniformityNormalized [NUMERICAL]
# 	438 : GrayLevelNonUniformity [NUMERICAL]
# 	397 : RunEntropy [NUMERICAL]
# 	382 : LongRunLowGrayLevelEmphasis [NUMERICAL]
# 	374 : LowGrayLevelRunEmphasis [NUMERICAL]
# 	373 : LongRunHighGrayLevelEmphasis [NUMERICAL]
# 	324 : ShortRunLowGrayLevelEmphasis [NUMERICAL]
# 	223 : GrayLevelVariance [NUMERICAL]
# 	198 : ShortRunEmphasis [NUMERICAL]
# 	191 : RunLengthNonUniformityNormalized [NUMERICAL]
# 	190 : LongRunEmphasis [NUMERICAL]
# 	182 : RunVariance [NUMERICAL]
# 	162 : RunLengthNonUniformity [NUMERICAL]
# 	141 : RunPercentage [NUMERICAL]
#
# Condition type in nodes:
# 	6088 : HigherCondition
# Condition type in nodes with depth <= 0:
# 	300 : HigherCondition
# Condition type in nodes with depth <= 1:
# 	899 : HigherCondition
# Condition type in nodes with depth <= 2:
# 	1859 : HigherCondition
# Condition type in nodes with depth <= 3:
# 	3037 : HigherCondition
# Condition type in nodes with depth <= 5:
# 	5017 : HigherCondition
# Node format: NOT_SET
#
# Training OOB:
# 	trees: 1, Out-of-bag evaluation: accuracy:0.971513 logloss:1.02678
# 	trees: 13, Out-of-bag evaluation: accuracy:0.958303 logloss:0.930701
# 	trees: 23, Out-of-bag evaluation: accuracy:0.963636 logloss:0.529837
# 	trees: 33, Out-of-bag evaluation: accuracy:0.964119 logloss:0.434467
# 	trees: 43, Out-of-bag evaluation: accuracy:0.963958 logloss:0.349232
# 	trees: 53, Out-of-bag evaluation: accuracy:0.966595 logloss:0.347302
# 	trees: 64, Out-of-bag evaluation: accuracy:0.966756 logloss:0.265423
# 	trees: 74, Out-of-bag evaluation: accuracy:0.964441 logloss:0.266374
# 	trees: 85, Out-of-bag evaluation: accuracy:0.961805 logloss:0.262182
# 	trees: 95, Out-of-bag evaluation: accuracy:0.95933 logloss:0.261646
# 	trees: 105, Out-of-bag evaluation: accuracy:0.961966 logloss:0.26297
# 	trees: 115, Out-of-bag evaluation: accuracy:0.964602 logloss:0.263316
# 	trees: 125, Out-of-bag evaluation: accuracy:0.96428 logloss:0.262592
# 	trees: 135, Out-of-bag evaluation: accuracy:0.96428 logloss:0.262609
# 	trees: 145, Out-of-bag evaluation: accuracy:0.962127 logloss:0.263644
# 	trees: 155, Out-of-bag evaluation: accuracy:0.966756 logloss:0.264059
# 	trees: 165, Out-of-bag evaluation: accuracy:0.961805 logloss:0.26262
# 	trees: 175, Out-of-bag evaluation: accuracy:0.96428 logloss:0.262113
# 	trees: 185, Out-of-bag evaluation: accuracy:0.964441 logloss:0.262808
# 	trees: 195, Out-of-bag evaluation: accuracy:0.967077 logloss:0.262787
# 	trees: 205, Out-of-bag evaluation: accuracy:0.964441 logloss:0.263439
# 	trees: 215, Out-of-bag evaluation: accuracy:0.964441 logloss:0.263535
# 	trees: 225, Out-of-bag evaluation: accuracy:0.964602 logloss:0.263346
# 	trees: 236, Out-of-bag evaluation: accuracy:0.964602 logloss:0.263881
# 	trees: 246, Out-of-bag evaluation: accuracy:0.964441 logloss:0.262509
# 	trees: 256, Out-of-bag evaluation: accuracy:0.964602 logloss:0.262184
# 	trees: 266, Out-of-bag evaluation: accuracy:0.961966 logloss:0.263017
# 	trees: 276, Out-of-bag evaluation: accuracy:0.959652 logloss:0.26318
# 	trees: 286, Out-of-bag evaluation: accuracy:0.959491 logloss:0.263712
# 	trees: 296, Out-of-bag evaluation: accuracy:0.962127 logloss:0.264415
# 	trees: 300, Out-of-bag evaluation: accuracy:0.959491 logloss:0.26457

# %%
# Model features
model.make_inspector().features()
# Out:
# ["GrayLevelNonUniformity" (1; #0),
#  "GrayLevelNonUniformityNormalized" (1; #1),
#  "GrayLevelVariance" (1; #2),
#  "HighGrayLevelRunEmphasis" (1; #3),
#  "LongRunEmphasis" (1; #4),
#  "LongRunHighGrayLevelEmphasis" (1; #5),
#  "LongRunLowGrayLevelEmphasis" (1; #6),
#  "LowGrayLevelRunEmphasis" (1; #7),
#  "RunEntropy" (1; #8),
#  "RunLengthNonUniformity" (1; #9),
#  "RunLengthNonUniformityNormalized" (1; #10),
#  "RunPercentage" (1; #11),
#  "RunVariance" (1; #12),
#  "ShortRunEmphasis" (1; #13),
#  "ShortRunHighGrayLevelEmphasis" (1; #14),
#  "ShortRunLowGrayLevelEmphasis" (1; #15)]

# %%
# Feature importance
model.make_inspector().variable_importances()
# Out:
# {'INV_MEAN_MIN_DEPTH': [("ShortRunHighGrayLevelEmphasis" (1; #14),
#    0.25246538996597917),
#   ("HighGrayLevelRunEmphasis" (1; #3), 0.2446722995117674),
#   ("LongRunHighGrayLevelEmphasis" (1; #5), 0.21828212587221518),
#   ("GrayLevelNonUniformityNormalized" (1; #1), 0.20499230906008123),
#   ("LongRunLowGrayLevelEmphasis" (1; #6), 0.2023303679883221),
#   ("GrayLevelNonUniformity" (1; #0), 0.1989364178160454),
#   ("LowGrayLevelRunEmphasis" (1; #7), 0.19370433999101488),
#   ("RunEntropy" (1; #8), 0.19028446830421952),
#   ("ShortRunLowGrayLevelEmphasis" (1; #15), 0.18425610411720283),
#   ("GrayLevelVariance" (1; #2), 0.17222901082281555),
#   ("LongRunEmphasis" (1; #4), 0.17138882416545811),
#   ("RunLengthNonUniformityNormalized" (1; #10), 0.16960310798162145),
#   ("RunPercentage" (1; #11), 0.16918963977469753),
#   ("RunVariance" (1; #12), 0.1685696637558794),
#   ("RunLengthNonUniformity" (1; #9), 0.1683491131425743),
#   ("ShortRunEmphasis" (1; #13), 0.16685740961220893)],
#  'SUM_SCORE': [("ShortRunHighGrayLevelEmphasis" (1; #14), 168119.53873188514),
#   ("HighGrayLevelRunEmphasis" (1; #3), 146185.9252757904),
#   ("LongRunHighGrayLevelEmphasis" (1; #5), 99900.43610065668),
#   ("LongRunLowGrayLevelEmphasis" (1; #6), 60114.07683087171),
#   ("LowGrayLevelRunEmphasis" (1; #7), 42979.62538356933),
#   ("GrayLevelNonUniformityNormalized" (1; #1), 36008.44864769452),
#   ("ShortRunLowGrayLevelEmphasis" (1; #15), 30882.219475847047),
#   ("GrayLevelNonUniformity" (1; #0), 30488.283510799738),
#   ("RunEntropy" (1; #8), 20979.417471811896),
#   ("GrayLevelVariance" (1; #2), 7395.785875950415),
#   ("LongRunEmphasis" (1; #4), 6755.000494576872),
#   ("RunPercentage" (1; #11), 6327.264082722631),
#   ("RunLengthNonUniformityNormalized" (1; #10), 6013.895044483048),
#   ("RunLengthNonUniformity" (1; #9), 5780.34798189952),
#   ("RunVariance" (1; #12), 5158.956348147462),
#   ("ShortRunEmphasis" (1; #13), 3236.8213501822715)],
#  'NUM_AS_ROOT': [("ShortRunHighGrayLevelEmphasis" (1; #14), 91.0),
#   ("HighGrayLevelRunEmphasis" (1; #3), 76.0),
#   ("LongRunHighGrayLevelEmphasis" (1; #5), 58.0),
#   ("LongRunLowGrayLevelEmphasis" (1; #6), 34.0),
#   ("LowGrayLevelRunEmphasis" (1; #7), 21.0),
#   ("ShortRunLowGrayLevelEmphasis" (1; #15), 11.0),
#   ("GrayLevelNonUniformity" (1; #0), 7.0),
#   ("GrayLevelNonUniformityNormalized" (1; #1), 1.0),
#   ("LongRunEmphasis" (1; #4), 1.0)],
#  'NUM_NODES': [("ShortRunHighGrayLevelEmphasis" (1; #14), 573.0),
#   ("GrayLevelNonUniformityNormalized" (1; #1), 552.0),
#   ("HighGrayLevelRunEmphasis" (1; #3), 547.0),
#   ("GrayLevelNonUniformity" (1; #0), 532.0),
#   ("RunEntropy" (1; #8), 489.0),
#   ("LowGrayLevelRunEmphasis" (1; #7), 454.0),
#   ("LongRunLowGrayLevelEmphasis" (1; #6), 453.0),
#   ("LongRunHighGrayLevelEmphasis" (1; #5), 428.0),
#   ("ShortRunLowGrayLevelEmphasis" (1; #15), 397.0),
#   ("GrayLevelVariance" (1; #2), 288.0),
#   ("LongRunEmphasis" (1; #4), 248.0),
#   ("ShortRunEmphasis" (1; #13), 247.0),
#   ("RunLengthNonUniformityNormalized" (1; #10), 241.0),
#   ("RunVariance" (1; #12), 235.0),
#   ("RunLengthNonUniformity" (1; #9), 216.0),
#   ("RunPercentage" (1; #11), 188.0)]}

# %%
# Model self evaluation
model.make_inspector().evaluation()
# Out:
# Evaluation(num_examples=3308, accuracy=0.9594907338543593, loss=0.2645701792398633, rmse=None, ndcg=None, aucs=None, auuc=None, qini=None)

# %%
logs = model.make_inspector().training_logs()

plt.figure(figsize=(12, 4))
plt.subplot(1, 2, 1)
plt.plot([log.num_trees for log in logs], [log.evaluation.accuracy for log in logs])
plt.xlabel("Number of trees")
plt.ylabel("Accuracy (out-of-bag)")
plt.subplot(1, 2, 2)
plt.plot([log.num_trees for log in logs], [log.evaluation.loss for log in logs])
plt.xlabel("Number of trees")
plt.ylabel("Logloss (out-of-bag)")
plt.show()

# %% [markdown]
# Calculate the score of our hold-out validation dataset

# %%
predictions = model.predict(val_ds)
y_true      = validation_data["label"]

from sklearn.metrics import roc_auc_score
ROC_AUC = roc_auc_score(y_true, predictions)
print("The ROC AUC score is %.5f" % ROC_AUC )
# Out:
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 62ms/step
# The ROC AUC score is 0.99908

# %%
# Compute binary classification metrics with sklearn
import numpy as np
from sklearn.metrics import (
    accuracy_score,
    precision_score,
    recall_score,
    f1_score,
    roc_auc_score,
    average_precision_score,
    confusion_matrix,
    classification_report,
    matthews_corrcoef,
    log_loss,
    brier_score_loss,
)

# Get predictions (probabilities or class labels)
preds = model.predict(test_ds)
# If model outputs probabilities, convert to labels by threshold 0.5
if preds.ndim == 2:
    # For TFDF classification, preds may be class probabilities with shape (N, 2)
    if preds.shape[1] == 2:
        pos_probs = preds[:, 1]
    else:
        # If single-probability column (positive class)
        pos_probs = preds[:, -1]
    y_pred = (pos_probs >= 0.5).astype(int)
else:
    # Already class labels
    y_pred = preds.astype(int)
    pos_probs = None

# Ground truth labels (must be 0/1 integers)
y_true = test_data["label"].astype(int).to_numpy()

# Core metrics
metrics = {}
metrics["accuracy"] = accuracy_score(y_true, y_pred)
metrics["precision"] = precision_score(y_true, y_pred, zero_division=0)
metrics["recall"] = recall_score(y_true, y_pred, zero_division=0)
metrics["f1"] = f1_score(y_true, y_pred, zero_division=0)
metrics["mcc"] = matthews_corrcoef(y_true, y_pred)

# Probabilistic metrics (only if we have probabilities)
if pos_probs is not None:
    metrics["roc_auc"] = roc_auc_score(y_true, pos_probs)
    metrics["pr_auc"] = average_precision_score(y_true, pos_probs)
    metrics["log_loss"] = log_loss(y_true, pos_probs, labels=[0,1])
    metrics["brier_score"] = brier_score_loss(y_true, pos_probs)

# Confusion matrix and detailed report
cm = confusion_matrix(y_true, y_pred, labels=[0,1])
report = classification_report(y_true, y_pred, digits=4)

print("Sklearn binary metrics:")
for k, v in metrics.items():
    print(f"{k}: {v:.4f}")
print("\nConfusion matrix:\n", cm)
print("\nClassification report:\n", report)
# Out:
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 71ms/step
# Sklearn binary metrics:
# accuracy: 0.9894
# precision: 0.8889
# recall: 0.9231
# f1: 0.9057
# mcc: 0.9002
# roc_auc: 0.9874
# pr_auc: 0.9641
# log_loss: 0.0402
# brier_score: 0.0083
#
# Confusion matrix:
#  [[888   6]
#  [  4  48]]
#
# Classification report:
#                precision    recall  f1-score   support
#
#            0     0.9955    0.9933    0.9944       894
#            1     0.8889    0.9231    0.9057        52
#
#     accuracy                         0.9894       946
#    macro avg     0.9422    0.9582    0.9500       946
# weighted avg     0.9897    0.9894    0.9895       946
