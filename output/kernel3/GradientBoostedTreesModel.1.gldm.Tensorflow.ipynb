# %%
# Import packages and modules
import numpy  as np
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow_decision_forests as tfdf

from sklearn.model_selection import train_test_split
# Out:
# 2026-08-15 04:55:35.109492: I tensorflow/core/util/port.cc:113] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2026-08-15 04:55:35.512020: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2026-08-15 04:55:40.544094: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
# Check the version of TensorFlow Decision Forests
print("Found TensorFlow Decision Forests v" + tfdf.__version__)
# Out:
# Found TensorFlow Decision Forests v1.9.1

# %%
datasetPath = 'dataset/firstorder/kernel5/dataset.csv'

# %%
# Parameters
datasetPath = "dataset/gldm/kernel3/1.dataset.csv"

# %%
# train/validation/test = 70/10/20
dataset = pd.read_csv(datasetPath)

train_data, temp_data = train_test_split(dataset, test_size=0.3, random_state=42)
validation_data, test_data = train_test_split(temp_data, test_size=2/3, random_state=42)

# %%
from sklearn.utils.class_weight import compute_class_weight

# tinh class weight tren tap train
classes = np.array([0, 1])
weights = compute_class_weight(class_weight="balanced", classes=classes, y=train_data["label"])
class_weight = {0: weights[0], 1: weights[1]}

# gan sample_weight cho tung dong
train_data["sample_weight"] = train_data["label"].map(class_weight)
validation_data["sample_weight"] = validation_data["label"].map(class_weight)
test_data["sample_weight"] = test_data["label"].map(class_weight)

# Convert the dataset into a TensorFlow dataset.
train_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    train_data, label="label", weight="sample_weight"
)         
val_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    validation_data, label="label", weight="sample_weight"
)
test_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    test_data, label="label", weight="sample_weight"
)
# Out:
# 2026-08-15 04:55:54.134954: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:984] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2026-08-15 04:55:54.136806: W tensorflow/core/common_runtime/gpu/gpu_device.cc:2251] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...

# %%
import keras

# %%
# %%time

# Train a Gradient Boosted Trees model.
model = tfdf.keras.GradientBoostedTreesModel()

# Add evaluation metrics
model.compile(
    metrics=["accuracy"]
)
model.fit(x=train_ds)

# # Train a Gradient Boosted Trees model.
# model = tfdf.keras.GradientBoostedTreesModel(num_trees=1500)
# model.fit(train_ds)
# Out:
# Use /tmp/tmp3ntacym4 as temporary training directory
# Reading training dataset...
# [WARNING 26-08-15 04:55:54.2877 UTC gradient_boosted_trees.cc:1840] "goss_alpha" set but "sampling_method" not equal to "GOSS".
# [WARNING 26-08-15 04:55:54.2879 UTC gradient_boosted_trees.cc:1851] "goss_beta" set but "sampling_method" not equal to "GOSS".
# [WARNING 26-08-15 04:55:54.2879 UTC gradient_boosted_trees.cc:1865] "selective_gradient_boosting_ratio" set but "sampling_method" not equal to "SELGB".
# Training dataset read in 0:00:02.687611. Found 3308 examples.
# Training model...
# Model trained in 0:00:00.424232
# Compiling model...
# [INFO 26-08-15 04:55:57.4299 UTC kernel.cc:1233] Loading model from path /tmp/tmp3ntacym4/model/ with prefix 8589c908da0e4696
# [INFO 26-08-15 04:55:57.4329 UTC quick_scorer_extended.cc:911] The binary was compiled without AVX2 support, but your CPU supports it. Enable it for faster model inference.
# [INFO 26-08-15 04:55:57.4330 UTC abstract_model.cc:1362] Engine "GradientBoostedTreesQuickScorerExtended" built
# [INFO 26-08-15 04:55:57.4331 UTC kernel.cc:1061] Use fast generic engine
# Model compiled.
# CPU times: user 6.51 s, sys: 436 ms, total: 6.95 s
# Wall time: 6.37 s

# %%
# Evaluate the model
evaluate = model.evaluate(val_ds, return_dict=True)
print()

for name, value in evaluate.items():
    print(f"{name}: {value:.4f}")
# Out:
# WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 1/1 [==============================] - ETA: 0s - loss: 0.0000e+00 - accuracy: 0.9894
# 1/1 [==============================] - 3s 3s/step - loss: 0.0000e+00 - accuracy: 0.9894
# loss: 0.0000
# accuracy: 0.9894

# %%
# Model Summary
model.summary()
# Out:
# Model: "gradient_boosted_trees_model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
# =================================================================
# Total params: 1 (1.00 Byte)
# Trainable params: 0 (0.00 Byte)
# Non-trainable params: 1 (1.00 Byte)
# _________________________________________________________________
# Type: "GRADIENT_BOOSTED_TREES"
# Task: CLASSIFICATION
# Label: "__LABEL"
#
# Input Features (14):
# 	DependenceEntropy
# 	DependenceNonUniformity
# 	DependenceNonUniformityNormalized
# 	DependenceVariance
# 	GrayLevelNonUniformity
# 	GrayLevelVariance
# 	HighGrayLevelEmphasis
# 	LargeDependenceEmphasis
# 	LargeDependenceHighGrayLevelEmphasis
# 	LargeDependenceLowGrayLevelEmphasis
# 	LowGrayLevelEmphasis
# 	SmallDependenceEmphasis
# 	SmallDependenceHighGrayLevelEmphasis
# 	SmallDependenceLowGrayLevelEmphasis
#
# Trained with weights
#
# Variable Importance: INV_MEAN_MIN_DEPTH:
#     1.                "HighGrayLevelEmphasis"  1.000000 ################
#     2.                    "DependenceEntropy"  0.274694 #
#     3. "SmallDependenceHighGrayLevelEmphasis"  0.214362
#     4.  "LargeDependenceLowGrayLevelEmphasis"  0.201013
#     5.                 "LowGrayLevelEmphasis"  0.200370
#     6.               "GrayLevelNonUniformity"  0.193697
#     7.  "SmallDependenceLowGrayLevelEmphasis"  0.186891
#     8. "LargeDependenceHighGrayLevelEmphasis"  0.182052
#     9.                   "DependenceVariance"  0.180066
#    10.                    "GrayLevelVariance"  0.178824
#    11.              "LargeDependenceEmphasis"  0.177663
#    12.              "DependenceNonUniformity"  0.177501
#    13.              "SmallDependenceEmphasis"  0.176758
#    14.    "DependenceNonUniformityNormalized"  0.176553
#
# Variable Importance: NUM_AS_ROOT:
#     1. "HighGrayLevelEmphasis" 45.000000
#
# Variable Importance: NUM_NODES:
#     1.                    "DependenceEntropy" 213.000000 ################
#     2.                "HighGrayLevelEmphasis" 205.000000 ###############
#     3. "SmallDependenceHighGrayLevelEmphasis" 102.000000 #######
#     4.                 "LowGrayLevelEmphasis" 101.000000 #######
#     5.               "GrayLevelNonUniformity" 94.000000 ######
#     6.  "LargeDependenceLowGrayLevelEmphasis" 79.000000 #####
#     7.  "SmallDependenceLowGrayLevelEmphasis" 64.000000 ####
#     8. "LargeDependenceHighGrayLevelEmphasis" 45.000000 ##
#     9.                    "GrayLevelVariance" 32.000000 #
#    10.                   "DependenceVariance" 30.000000 #
#    11.              "LargeDependenceEmphasis" 26.000000 #
#    12.              "DependenceNonUniformity" 14.000000
#    13.    "DependenceNonUniformityNormalized"  8.000000
#    14.              "SmallDependenceEmphasis"  7.000000
#
# Variable Importance: SUM_SCORE:
#     1.                "HighGrayLevelEmphasis" 3303.961131 ################
#     2.                    "DependenceEntropy" 285.781262 #
#     3. "SmallDependenceHighGrayLevelEmphasis" 213.635395 #
#     4.                 "LowGrayLevelEmphasis" 105.734600
#     5.  "SmallDependenceLowGrayLevelEmphasis" 65.091670
#     6.               "GrayLevelNonUniformity" 25.798703
#     7.  "LargeDependenceLowGrayLevelEmphasis" 16.843784
#     8.                   "DependenceVariance"  7.911055
#     9. "LargeDependenceHighGrayLevelEmphasis"  7.311413
#    10.              "LargeDependenceEmphasis"  7.280117
#    11.              "DependenceNonUniformity"  4.744938
#    12.                    "GrayLevelVariance"  1.982815
#    13.    "DependenceNonUniformityNormalized"  0.405910
#    14.              "SmallDependenceEmphasis"  0.032880
#
#
#
# Loss: BINOMIAL_LOG_LIKELIHOOD
# Validation loss value: 0.307826
# Number of trees per iteration: 1
# Node format: NOT_SET
# Number of trees: 45
# Total number of nodes: 2085
#
# Number of nodes by tree:
# Count: 45 Average: 46.3333 StdDev: 3.81809
# Min: 35 Max: 55 Ignored: 0
# ----------------------------------------------
# [ 35, 36)  1   2.22%   2.22% #
# [ 36, 37)  0   0.00%   2.22%
# [ 37, 38)  0   0.00%   2.22%
# [ 38, 39)  0   0.00%   2.22%
# [ 39, 40)  1   2.22%   4.44% #
# [ 40, 41)  0   0.00%   4.44%
# [ 41, 42)  1   2.22%   6.67% #
# [ 42, 43)  0   0.00%   6.67%
# [ 43, 44) 10  22.22%  28.89% ##########
# [ 44, 45)  0   0.00%  28.89%
# [ 45, 46)  9  20.00%  48.89% #########
# [ 46, 47)  0   0.00%  48.89%
# [ 47, 48)  8  17.78%  66.67% ########
# [ 48, 49)  0   0.00%  66.67%
# [ 49, 50)  6  13.33%  80.00% ######
# [ 50, 51)  0   0.00%  80.00%
# [ 51, 52)  7  15.56%  95.56% #######
# [ 52, 53)  0   0.00%  95.56%
# [ 53, 54)  1   2.22%  97.78% #
# [ 54, 55]  1   2.22% 100.00% #
#
# Depth by leafs:
# Count: 1065 Average: 4.68732 StdDev: 0.538542
# Min: 2 Max: 5 Ignored: 0
# ----------------------------------------------
# [ 2, 3)   2   0.19%   0.19%
# [ 3, 4)  34   3.19%   3.38%
# [ 4, 5) 259  24.32%  27.70% ###
# [ 5, 5] 770  72.30% 100.00% ##########
#
# Number of training obs by leaf:
# Count: 1065 Average: 126.38 StdDev: 449.869
# Min: 5 Max: 2503 Ignored: 0
# ----------------------------------------------
# [    5,  129) 931  87.42%  87.42% ##########
# [  129,  254)  83   7.79%  95.21% #
# [  254,  379)   3   0.28%  95.49%
# [  379,  504)   1   0.09%  95.59%
# [  504,  629)   0   0.00%  95.59%
# [  629,  754)   1   0.09%  95.68%
# [  754,  879)   1   0.09%  95.77%
# [  879, 1004)   0   0.00%  95.77%
# [ 1004, 1129)   0   0.00%  95.77%
# [ 1129, 1254)   0   0.00%  95.77%
# [ 1254, 1379)   0   0.00%  95.77%
# [ 1379, 1504)   1   0.09%  95.87%
# [ 1504, 1629)   1   0.09%  95.96%
# [ 1629, 1754)   0   0.00%  95.96%
# [ 1754, 1879)   1   0.09%  96.06%
# [ 1879, 2004)   1   0.09%  96.15%
# [ 2004, 2129)   0   0.00%  96.15%
# [ 2129, 2254)  15   1.41%  97.56%
# [ 2254, 2379)  23   2.16%  99.72%
# [ 2379, 2503]   3   0.28% 100.00%
#
# Attribute in nodes:
# 	213 : DependenceEntropy [NUMERICAL]
# 	205 : HighGrayLevelEmphasis [NUMERICAL]
# 	102 : SmallDependenceHighGrayLevelEmphasis [NUMERICAL]
# 	101 : LowGrayLevelEmphasis [NUMERICAL]
# 	94 : GrayLevelNonUniformity [NUMERICAL]
# 	79 : LargeDependenceLowGrayLevelEmphasis [NUMERICAL]
# 	64 : SmallDependenceLowGrayLevelEmphasis [NUMERICAL]
# 	45 : LargeDependenceHighGrayLevelEmphasis [NUMERICAL]
# 	32 : GrayLevelVariance [NUMERICAL]
# 	30 : DependenceVariance [NUMERICAL]
# 	26 : LargeDependenceEmphasis [NUMERICAL]
# 	14 : DependenceNonUniformity [NUMERICAL]
# 	8 : DependenceNonUniformityNormalized [NUMERICAL]
# 	7 : SmallDependenceEmphasis [NUMERICAL]
#
# Attribute in nodes with depth <= 0:
# 	45 : HighGrayLevelEmphasis [NUMERICAL]
#
# Attribute in nodes with depth <= 1:
# 	84 : HighGrayLevelEmphasis [NUMERICAL]
# 	25 : DependenceEntropy [NUMERICAL]
# 	17 : SmallDependenceHighGrayLevelEmphasis [NUMERICAL]
# 	3 : SmallDependenceLowGrayLevelEmphasis [NUMERICAL]
# 	3 : LowGrayLevelEmphasis [NUMERICAL]
# 	3 : GrayLevelNonUniformity [NUMERICAL]
#
# Attribute in nodes with depth <= 2:
# 	119 : HighGrayLevelEmphasis [NUMERICAL]
# 	66 : DependenceEntropy [NUMERICAL]
# 	34 : LowGrayLevelEmphasis [NUMERICAL]
# 	33 : LargeDependenceLowGrayLevelEmphasis [NUMERICAL]
# 	23 : SmallDependenceHighGrayLevelEmphasis [NUMERICAL]
# 	18 : GrayLevelNonUniformity [NUMERICAL]
# 	8 : SmallDependenceLowGrayLevelEmphasis [NUMERICAL]
# 	4 : LargeDependenceHighGrayLevelEmphasis [NUMERICAL]
# 	4 : GrayLevelVariance [NUMERICAL]
# 	4 : DependenceVariance [NUMERICAL]
#
# Attribute in nodes with depth <= 3:
# 	162 : HighGrayLevelEmphasis [NUMERICAL]
# 	147 : DependenceEntropy [NUMERICAL]
# 	71 : LowGrayLevelEmphasis [NUMERICAL]
# 	68 : SmallDependenceHighGrayLevelEmphasis [NUMERICAL]
# 	53 : LargeDependenceLowGrayLevelEmphasis [NUMERICAL]
# 	47 : GrayLevelNonUniformity [NUMERICAL]
# 	25 : LargeDependenceHighGrayLevelEmphasis [NUMERICAL]
# 	22 : SmallDependenceLowGrayLevelEmphasis [NUMERICAL]
# 	15 : GrayLevelVariance [NUMERICAL]
# 	11 : DependenceVariance [NUMERICAL]
# 	8 : DependenceNonUniformity [NUMERICAL]
# 	3 : SmallDependenceEmphasis [NUMERICAL]
# 	2 : LargeDependenceEmphasis [NUMERICAL]
# 	1 : DependenceNonUniformityNormalized [NUMERICAL]
#
# Attribute in nodes with depth <= 5:
# 	213 : DependenceEntropy [NUMERICAL]
# 	205 : HighGrayLevelEmphasis [NUMERICAL]
# 	102 : SmallDependenceHighGrayLevelEmphasis [NUMERICAL]
# 	101 : LowGrayLevelEmphasis [NUMERICAL]
# 	94 : GrayLevelNonUniformity [NUMERICAL]
# 	79 : LargeDependenceLowGrayLevelEmphasis [NUMERICAL]
# 	64 : SmallDependenceLowGrayLevelEmphasis [NUMERICAL]
# 	45 : LargeDependenceHighGrayLevelEmphasis [NUMERICAL]
# 	32 : GrayLevelVariance [NUMERICAL]
# 	30 : DependenceVariance [NUMERICAL]
# 	26 : LargeDependenceEmphasis [NUMERICAL]
# 	14 : DependenceNonUniformity [NUMERICAL]
# 	8 : DependenceNonUniformityNormalized [NUMERICAL]
# 	7 : SmallDependenceEmphasis [NUMERICAL]
#
# Condition type in nodes:
# 	1020 : HigherCondition
# Condition type in nodes with depth <= 0:
# 	45 : HigherCondition
# Condition type in nodes with depth <= 1:
# 	135 : HigherCondition
# Condition type in nodes with depth <= 2:
# 	313 : HigherCondition
# Condition type in nodes with depth <= 3:
# 	635 : HigherCondition
# Condition type in nodes with depth <= 5:
# 	1020 : HigherCondition
#
# Training logs:
# Number of iteration to final model: 45
# 	Iter:1 train-loss:1.202698 valid-loss:1.220865  train-accuracy:0.989478 valid-accuracy:0.960400
# 	Iter:2 train-loss:1.050781 valid-loss:1.078612  train-accuracy:0.993181 valid-accuracy:0.964230
# 	Iter:3 train-loss:0.924985 valid-loss:0.961528  train-accuracy:0.992299 valid-accuracy:0.964230
# 	Iter:4 train-loss:0.818117 valid-loss:0.863816  train-accuracy:0.993181 valid-accuracy:0.964230
# 	Iter:5 train-loss:0.727231 valid-loss:0.780993  train-accuracy:0.992476 valid-accuracy:0.964230
# 	Iter:6 train-loss:0.648223 valid-loss:0.712964  train-accuracy:0.993181 valid-accuracy:0.964230
# 	Iter:16 train-loss:0.223020 valid-loss:0.411635  train-accuracy:0.997355 valid-accuracy:0.968060
# 	Iter:26 train-loss:0.086869 valid-loss:0.357067  train-accuracy:0.998237 valid-accuracy:0.966145
# 	Iter:36 train-loss:0.036439 valid-loss:0.319428  train-accuracy:0.999118 valid-accuracy:0.936121
# 	Iter:46 train-loss:0.016612 valid-loss:0.315229  train-accuracy:0.999471 valid-accuracy:0.908012
# 	Iter:56 train-loss:0.007944 valid-loss:0.327501  train-accuracy:0.999824 valid-accuracy:0.909927
# 	Iter:66 train-loss:0.004580 valid-loss:0.346180  train-accuracy:1.000000 valid-accuracy:0.909927

# %%
# Model features
model.make_inspector().features()
# Out:
# ["DependenceEntropy" (1; #0),
#  "DependenceNonUniformity" (1; #1),
#  "DependenceNonUniformityNormalized" (1; #2),
#  "DependenceVariance" (1; #3),
#  "GrayLevelNonUniformity" (1; #4),
#  "GrayLevelVariance" (1; #5),
#  "HighGrayLevelEmphasis" (1; #6),
#  "LargeDependenceEmphasis" (1; #7),
#  "LargeDependenceHighGrayLevelEmphasis" (1; #8),
#  "LargeDependenceLowGrayLevelEmphasis" (1; #9),
#  "LowGrayLevelEmphasis" (1; #10),
#  "SmallDependenceEmphasis" (1; #11),
#  "SmallDependenceHighGrayLevelEmphasis" (1; #12),
#  "SmallDependenceLowGrayLevelEmphasis" (1; #13)]

# %%
# Feature importance
model.make_inspector().variable_importances()
# Out:
# {'INV_MEAN_MIN_DEPTH': [("HighGrayLevelEmphasis" (1; #6), 1.0),
#   ("DependenceEntropy" (1; #0), 0.27469390265166377),
#   ("SmallDependenceHighGrayLevelEmphasis" (1; #12), 0.21436243858832804),
#   ("LargeDependenceLowGrayLevelEmphasis" (1; #9), 0.2010128340974662),
#   ("LowGrayLevelEmphasis" (1; #10), 0.20037010322578436),
#   ("GrayLevelNonUniformity" (1; #4), 0.19369676376723213),
#   ("SmallDependenceLowGrayLevelEmphasis" (1; #13), 0.1868906485771934),
#   ("LargeDependenceHighGrayLevelEmphasis" (1; #8), 0.18205186842184737),
#   ("DependenceVariance" (1; #3), 0.1800659386954377),
#   ("GrayLevelVariance" (1; #5), 0.1788238928957013),
#   ("LargeDependenceEmphasis" (1; #7), 0.17766287806540124),
#   ("DependenceNonUniformity" (1; #1), 0.1775006081123429),
#   ("SmallDependenceEmphasis" (1; #11), 0.17675800247867418),
#   ("DependenceNonUniformityNormalized" (1; #2), 0.17655262946207687)],
#  'NUM_AS_ROOT': [("HighGrayLevelEmphasis" (1; #6), 45.0)],
#  'SUM_SCORE': [("HighGrayLevelEmphasis" (1; #6), 3303.9611313034884),
#   ("DependenceEntropy" (1; #0), 285.7812618407793),
#   ("SmallDependenceHighGrayLevelEmphasis" (1; #12), 213.63539519446627),
#   ("LowGrayLevelEmphasis" (1; #10), 105.73459964075663),
#   ("SmallDependenceLowGrayLevelEmphasis" (1; #13), 65.09167023749397),
#   ("GrayLevelNonUniformity" (1; #4), 25.798702727608696),
#   ("LargeDependenceLowGrayLevelEmphasis" (1; #9), 16.843784401690108),
#   ("DependenceVariance" (1; #3), 7.911055293346058),
#   ("LargeDependenceHighGrayLevelEmphasis" (1; #8), 7.311413076451172),
#   ("LargeDependenceEmphasis" (1; #7), 7.280117306343369),
#   ("DependenceNonUniformity" (1; #1), 4.744938389156983),
#   ("GrayLevelVariance" (1; #5), 1.982815058784845),
#   ("DependenceNonUniformityNormalized" (1; #2), 0.4059101208469635),
#   ("SmallDependenceEmphasis" (1; #11), 0.0328801789705362)],
#  'NUM_NODES': [("DependenceEntropy" (1; #0), 213.0),
#   ("HighGrayLevelEmphasis" (1; #6), 205.0),
#   ("SmallDependenceHighGrayLevelEmphasis" (1; #12), 102.0),
#   ("LowGrayLevelEmphasis" (1; #10), 101.0),
#   ("GrayLevelNonUniformity" (1; #4), 94.0),
#   ("LargeDependenceLowGrayLevelEmphasis" (1; #9), 79.0),
#   ("SmallDependenceLowGrayLevelEmphasis" (1; #13), 64.0),
#   ("LargeDependenceHighGrayLevelEmphasis" (1; #8), 45.0),
#   ("GrayLevelVariance" (1; #5), 32.0),
#   ("DependenceVariance" (1; #3), 30.0),
#   ("LargeDependenceEmphasis" (1; #7), 26.0),
#   ("DependenceNonUniformity" (1; #1), 14.0),
#   ("DependenceNonUniformityNormalized" (1; #2), 8.0),
#   ("SmallDependenceEmphasis" (1; #11), 7.0)]}

# %%
# Model self evaluation
model.make_inspector().evaluation()
# Out:
# Evaluation(num_examples=None, accuracy=0.9361209869384766, loss=0.30782580375671387, rmse=None, ndcg=None, aucs=None, auuc=None, qini=None)

# %%
logs = model.make_inspector().training_logs()

plt.figure(figsize=(12, 4))
plt.subplot(1, 2, 1)
plt.plot([log.num_trees for log in logs], [log.evaluation.accuracy for log in logs])
plt.xlabel("Number of trees")
plt.ylabel("Accuracy (out-of-bag)")
plt.subplot(1, 2, 2)
plt.plot([log.num_trees for log in logs], [log.evaluation.loss for log in logs])
plt.xlabel("Number of trees")
plt.ylabel("Logloss (out-of-bag)")
plt.show()

# %% [markdown]
# Calculate the score of our hold-out validation dataset

# %%
predictions = model.predict(val_ds)
y_true      = validation_data["label"]

from sklearn.metrics import roc_auc_score
ROC_AUC = roc_auc_score(y_true, predictions)
print("The ROC AUC score is %.5f" % ROC_AUC )
# Out:
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 71ms/step
# The ROC AUC score is 0.99647

# %%
# Compute binary classification metrics with sklearn
import numpy as np
from sklearn.metrics import (
    accuracy_score,
    precision_score,
    recall_score,
    f1_score,
    roc_auc_score,
    average_precision_score,
    confusion_matrix,
    classification_report,
    matthews_corrcoef,
    log_loss,
    brier_score_loss,
)

# Get predictions (probabilities or class labels)
preds = model.predict(test_ds)
# If model outputs probabilities, convert to labels by threshold 0.5
if preds.ndim == 2:
    # For TFDF classification, preds may be class probabilities with shape (N, 2)
    if preds.shape[1] == 2:
        pos_probs = preds[:, 1]
    else:
        # If single-probability column (positive class)
        pos_probs = preds[:, -1]
    y_pred = (pos_probs >= 0.5).astype(int)
else:
    # Already class labels
    y_pred = preds.astype(int)
    pos_probs = None

# Ground truth labels (must be 0/1 integers)
y_true = test_data["label"].astype(int).to_numpy()

# Core metrics
metrics = {}
metrics["accuracy"] = accuracy_score(y_true, y_pred)
metrics["precision"] = precision_score(y_true, y_pred, zero_division=0)
metrics["recall"] = recall_score(y_true, y_pred, zero_division=0)
metrics["f1"] = f1_score(y_true, y_pred, zero_division=0)
metrics["mcc"] = matthews_corrcoef(y_true, y_pred)

# Probabilistic metrics (only if we have probabilities)
if pos_probs is not None:
    metrics["roc_auc"] = roc_auc_score(y_true, pos_probs)
    metrics["pr_auc"] = average_precision_score(y_true, pos_probs)
    metrics["log_loss"] = log_loss(y_true, pos_probs, labels=[0,1])
    metrics["brier_score"] = brier_score_loss(y_true, pos_probs)

# Confusion matrix and detailed report
cm = confusion_matrix(y_true, y_pred, labels=[0,1])
report = classification_report(y_true, y_pred, digits=4)

print("Sklearn binary metrics:")
for k, v in metrics.items():
    print(f"{k}: {v:.4f}")
print("\nConfusion matrix:\n", cm)
print("\nClassification report:\n", report)
# Out:
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 67ms/step
# Sklearn binary metrics:
# accuracy: 0.9863
# precision: 0.8000
# recall: 0.9565
# f1: 0.8713
# mcc: 0.8679
# roc_auc: 0.9853
# pr_auc: 0.9548
# log_loss: 0.0486
# brier_score: 0.0113
#
# Confusion matrix:
#  [[889  11]
#  [  2  44]]
#
# Classification report:
#                precision    recall  f1-score   support
#
#            0     0.9978    0.9878    0.9927       900
#            1     0.8000    0.9565    0.8713        46
#
#     accuracy                         0.9863       946
#    macro avg     0.8989    0.9721    0.9320       946
# weighted avg     0.9881    0.9863    0.9868       946
