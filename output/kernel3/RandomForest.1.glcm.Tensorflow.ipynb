# %%
# Import packages and modules
import numpy  as np
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow_decision_forests as tfdf

from sklearn.model_selection import train_test_split
# Out:
# 2026-08-15 05:09:40.316696: I tensorflow/core/util/port.cc:113] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2026-08-15 05:09:40.689419: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2026-08-15 05:09:45.440250: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
# Check the version of TensorFlow Decision Forests
print("Found TensorFlow Decision Forests v" + tfdf.__version__)
# Out:
# Found TensorFlow Decision Forests v1.9.1

# %%
datasetPath = 'dataset/firstorder/kernel5/dataset.csv'

# %%
# Parameters
datasetPath = "dataset/glcm/kernel3/1.dataset.csv"

# %%
# train/validation/test = 70/10/20
dataset = pd.read_csv(datasetPath)

train_data, temp_data = train_test_split(dataset, test_size=0.3, random_state=42)
validation_data, test_data = train_test_split(temp_data, test_size=2/3, random_state=42)

# %%
from sklearn.utils.class_weight import compute_class_weight

# tinh class weight tren tap train
classes = np.array([0, 1])
weights = compute_class_weight(class_weight="balanced", classes=classes, y=train_data["label"])
class_weight = {0: weights[0], 1: weights[1]}

# gan sample_weight cho tung dong
train_data["sample_weight"] = train_data["label"].map(class_weight)
validation_data["sample_weight"] = validation_data["label"].map(class_weight)
test_data["sample_weight"] = test_data["label"].map(class_weight)

# Convert the dataset into a TensorFlow dataset.
train_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    train_data, label="label", weight="sample_weight"
)         
val_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    validation_data, label="label", weight="sample_weight"
)
test_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    test_data, label="label", weight="sample_weight"
)
# Out:
# 2026-08-15 05:09:59.434725: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:984] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2026-08-15 05:09:59.435922: W tensorflow/core/common_runtime/gpu/gpu_device.cc:2251] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...

# %%
import keras

# %%
# %%time

# Train a Random Forest model.
model = tfdf.keras.RandomForestModel()

# Add evaluation metrics
model.compile(
    metrics=["accuracy"]
)
model.fit(x=train_ds)

# # Train a Gradient Boosted Trees model.
# model = tfdf.keras.GradientBoostedTreesModel(num_trees=1500)
# model.fit(train_ds)
# Out:
# Use /tmp/tmp_nwryjt8 as temporary training directory
# Reading training dataset...
# Training dataset read in 0:00:02.652747. Found 3308 examples.
# Training model...
# Model trained in 0:00:00.116999
# Compiling model...
# [INFO 26-08-15 05:10:02.3784 UTC kernel.cc:1233] Loading model from path /tmp/tmp_nwryjt8/model/ with prefix 9a6e1bad22764617
# [INFO 26-08-15 05:10:02.3933 UTC decision_forest.cc:734] Model loaded with 300 root(s), 11818 node(s), and 24 input feature(s).
# [INFO 26-08-15 05:10:02.3933 UTC abstract_model.cc:1362] Engine "RandomForestOptPred" built
# [INFO 26-08-15 05:10:02.3933 UTC kernel.cc:1061] Use fast generic engine
# Model compiled.
# CPU times: user 6.2 s, sys: 72.2 ms, total: 6.27 s
# Wall time: 6.01 s

# %%
# Evaluate the model
evaluate = model.evaluate(val_ds, return_dict=True)
print()

for name, value in evaluate.items():
    print(f"{name}: {value:.4f}")
# Out:
# WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 1/1 [==============================] - ETA: 0s - loss: 0.0000e+00 - accuracy: 0.9852
# 1/1 [==============================] - 3s 3s/step - loss: 0.0000e+00 - accuracy: 0.9852
# loss: 0.0000
# accuracy: 0.9852

# %%
# Model Summary
model.summary()
# Out:
# Model: "random_forest_model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
# =================================================================
# Total params: 1 (1.00 Byte)
# Trainable params: 0 (0.00 Byte)
# Non-trainable params: 1 (1.00 Byte)
# _________________________________________________________________
# Type: "RANDOM_FOREST"
# Task: CLASSIFICATION
# Label: "__LABEL"
#
# Input Features (24):
# 	Autocorrelation
# 	ClusterProminence
# 	ClusterShade
# 	ClusterTendency
# 	Contrast
# 	Correlation
# 	DifferenceAverage
# 	DifferenceEntropy
# 	DifferenceVariance
# 	Id
# 	Idm
# 	Idmn
# 	Idn
# 	Imc1
# 	Imc2
# 	InverseVariance
# 	JointAverage
# 	JointEnergy
# 	JointEntropy
# 	MCC
# 	MaximumProbability
# 	SumAverage
# 	SumEntropy
# 	SumSquares
#
# Trained with weights
#
# Variable Importance: INV_MEAN_MIN_DEPTH:
#     1.    "Autocorrelation"  0.263353 ################
#     2.       "JointAverage"  0.239813 ############
#     3.         "SumAverage"  0.237286 ###########
#     4.        "Correlation"  0.194097 #####
#     5.         "SumEntropy"  0.187537 ####
#     6.               "Imc1"  0.186290 ###
#     7.               "Imc2"  0.183576 ###
#     8.        "JointEnergy"  0.182194 ###
#     9.       "JointEntropy"  0.173632 #
#    10.       "ClusterShade"  0.173181 #
#    11.                "MCC"  0.171377 #
#    12.  "ClusterProminence"  0.171214 #
#    13.    "ClusterTendency"  0.168901 #
#    14. "DifferenceVariance"  0.168658 #
#    15. "MaximumProbability"  0.168350 #
#    16.                "Idm"  0.167716
#    17.           "Contrast"  0.165307
#    18.               "Idmn"  0.164106
#    19.                 "Id"  0.163765
#    20.  "DifferenceEntropy"  0.162826
#    21.                "Idn"  0.162513
#    22.         "SumSquares"  0.162340
#    23.    "InverseVariance"  0.162044
#    24.  "DifferenceAverage"  0.161928
#
# Variable Importance: NUM_AS_ROOT:
#     1.    "Autocorrelation" 90.000000 ################
#     2.       "JointAverage" 56.000000 #########
#     3.         "SumAverage" 55.000000 #########
#     4.        "JointEnergy" 22.000000 ###
#     5.         "SumEntropy" 21.000000 ###
#     6.       "JointEntropy" 12.000000 #
#     7.               "Imc1" 11.000000 #
#     8.                "Idm"  8.000000 #
#     9.               "Imc2"  8.000000 #
#    10.  "ClusterProminence"  7.000000
#    11.    "ClusterTendency"  4.000000
#    12.                 "Id"  4.000000
#    13. "MaximumProbability"  2.000000
#
# Variable Importance: NUM_NODES:
#     1.    "Autocorrelation" 552.000000 ################
#     2.         "SumAverage" 519.000000 ##############
#     3.       "JointAverage" 500.000000 ##############
#     4.        "Correlation" 365.000000 #########
#     5.         "SumEntropy" 332.000000 #######
#     6.       "ClusterShade" 317.000000 #######
#     7.               "Imc2" 308.000000 #######
#     8.               "Imc1" 301.000000 ######
#     9.        "JointEnergy" 230.000000 ####
#    10. "DifferenceVariance" 206.000000 ###
#    11.       "JointEntropy" 200.000000 ###
#    12. "MaximumProbability" 192.000000 ##
#    13.                "MCC" 179.000000 ##
#    14.                "Idm" 172.000000 ##
#    15.  "ClusterProminence" 160.000000 #
#    16.           "Contrast" 152.000000 #
#    17.    "ClusterTendency" 149.000000 #
#    18.                 "Id" 149.000000 #
#    19.                "Idn" 146.000000 #
#    20.    "InverseVariance" 142.000000
#    21.               "Idmn" 128.000000
#    22.         "SumSquares" 126.000000
#    23.  "DifferenceEntropy" 119.000000
#    24.  "DifferenceAverage" 115.000000
#
# Variable Importance: SUM_SCORE:
#     1.    "Autocorrelation" 214065.681712 ################
#     2.         "SumAverage" 159211.009808 ###########
#     3.       "JointAverage" 157744.670593 ###########
#     4.         "SumEntropy" 21100.615007 #
#     5.               "Imc2" 16103.334539 #
#     6.        "JointEnergy" 16012.657468 #
#     7.        "Correlation" 13515.463786
#     8.               "Imc1" 13356.836254
#     9.       "JointEntropy" 10981.821333
#    10. "MaximumProbability" 6786.125450
#    11.       "ClusterShade" 5935.371170
#    12.                "Idm" 5732.582225
#    13.    "ClusterTendency" 5036.106289
#    14.  "ClusterProminence" 4861.905993
#    15.                "MCC" 4617.300058
#    16. "DifferenceVariance" 3404.474490
#    17.                 "Id" 3325.665890
#    18.    "InverseVariance" 2819.347562
#    19.           "Contrast" 2650.746906
#    20.         "SumSquares" 2569.419028
#    21.               "Idmn" 2207.790695
#    22.                "Idn" 1881.634549
#    23.  "DifferenceEntropy" 1782.106349
#    24.  "DifferenceAverage" 1527.363374
#
#
#
# Winner takes all: true
# Out-of-bag evaluation: accuracy:0.971405 logloss:0.0864186
# Number of trees: 300
# Total number of nodes: 11818
#
# Number of nodes by tree:
# Count: 300 Average: 39.3933 StdDev: 6.22404
# Min: 25 Max: 65 Ignored: 0
# ----------------------------------------------
# [ 25, 27)  1   0.33%   0.33%
# [ 27, 29)  0   0.00%   0.33%
# [ 29, 31) 10   3.33%   3.67% ##
# [ 31, 33) 22   7.33%  11.00% #####
# [ 33, 35) 22   7.33%  18.33% #####
# [ 35, 37) 43  14.33%  32.67% ##########
# [ 37, 39) 40  13.33%  46.00% #########
# [ 39, 41) 37  12.33%  58.33% #########
# [ 41, 43) 35  11.67%  70.00% ########
# [ 43, 45) 24   8.00%  78.00% ######
# [ 45, 47) 25   8.33%  86.33% ######
# [ 47, 49)  7   2.33%  88.67% ##
# [ 49, 51) 16   5.33%  94.00% ####
# [ 51, 53)  7   2.33%  96.33% ##
# [ 53, 55)  6   2.00%  98.33% #
# [ 55, 57)  3   1.00%  99.33% #
# [ 57, 59)  1   0.33%  99.67%
# [ 59, 61)  0   0.00%  99.67%
# [ 61, 63)  0   0.00%  99.67%
# [ 63, 65]  1   0.33% 100.00%
#
# Depth by leafs:
# Count: 6059 Average: 5.39066 StdDev: 1.99033
# Min: 1 Max: 13 Ignored: 0
# ----------------------------------------------
# [  1,  2)   15   0.25%   0.25%
# [  2,  3)  231   3.81%   4.06% ##
# [  3,  4)  789  13.02%  17.08% ######
# [  4,  5) 1173  19.36%  36.44% #########
# [  5,  6) 1272  20.99%  57.44% ##########
# [  6,  7)  981  16.19%  73.63% ########
# [  7,  8)  676  11.16%  84.78% #####
# [  8,  9)  458   7.56%  92.34% ####
# [  9, 10)  261   4.31%  96.65% ##
# [ 10, 11)  125   2.06%  98.71% #
# [ 11, 12)   57   0.94%  99.65%
# [ 12, 13)   15   0.25%  99.90%
# [ 13, 13]    6   0.10% 100.00%
#
# Number of training obs by leaf:
# Count: 6059 Average: 163.789 StdDev: 527.667
# Min: 5 Max: 2937 Ignored: 0
# ----------------------------------------------
# [    5,  151) 5342  88.17%  88.17% ##########
# [  151,  298)  188   3.10%  91.27%
# [  298,  444)   99   1.63%  92.90%
# [  444,  591)   83   1.37%  94.27%
# [  591,  738)   24   0.40%  94.67%
# [  738,  884)   13   0.21%  94.88%
# [  884, 1031)    5   0.08%  94.97%
# [ 1031, 1178)    8   0.13%  95.10%
# [ 1178, 1324)    6   0.10%  95.20%
# [ 1324, 1471)    6   0.10%  95.30%
# [ 1471, 1618)    2   0.03%  95.33%
# [ 1618, 1764)    9   0.15%  95.48%
# [ 1764, 1911)   13   0.21%  95.69%
# [ 1911, 2058)   14   0.23%  95.92%
# [ 2058, 2204)    9   0.15%  96.07%
# [ 2204, 2351)   26   0.43%  96.50%
# [ 2351, 2498)   67   1.11%  97.61%
# [ 2498, 2644)   47   0.78%  98.38%
# [ 2644, 2791)   89   1.47%  99.85%
# [ 2791, 2937]    9   0.15% 100.00%
#
# Attribute in nodes:
# 	552 : Autocorrelation [NUMERICAL]
# 	519 : SumAverage [NUMERICAL]
# 	500 : JointAverage [NUMERICAL]
# 	365 : Correlation [NUMERICAL]
# 	332 : SumEntropy [NUMERICAL]
# 	317 : ClusterShade [NUMERICAL]
# 	308 : Imc2 [NUMERICAL]
# 	301 : Imc1 [NUMERICAL]
# 	230 : JointEnergy [NUMERICAL]
# 	206 : DifferenceVariance [NUMERICAL]
# 	200 : JointEntropy [NUMERICAL]
# 	192 : MaximumProbability [NUMERICAL]
# 	179 : MCC [NUMERICAL]
# 	172 : Idm [NUMERICAL]
# 	160 : ClusterProminence [NUMERICAL]
# 	152 : Contrast [NUMERICAL]
# 	149 : Id [NUMERICAL]
# 	149 : ClusterTendency [NUMERICAL]
# 	146 : Idn [NUMERICAL]
# 	142 : InverseVariance [NUMERICAL]
# 	128 : Idmn [NUMERICAL]
# 	126 : SumSquares [NUMERICAL]
# 	119 : DifferenceEntropy [NUMERICAL]
# 	115 : DifferenceAverage [NUMERICAL]
#
# Attribute in nodes with depth <= 0:
# 	90 : Autocorrelation [NUMERICAL]
# 	56 : JointAverage [NUMERICAL]
# 	55 : SumAverage [NUMERICAL]
# 	22 : JointEnergy [NUMERICAL]
# 	21 : SumEntropy [NUMERICAL]
# 	12 : JointEntropy [NUMERICAL]
# 	11 : Imc1 [NUMERICAL]
# 	8 : Imc2 [NUMERICAL]
# 	8 : Idm [NUMERICAL]
# 	7 : ClusterProminence [NUMERICAL]
# 	4 : Id [NUMERICAL]
# 	4 : ClusterTendency [NUMERICAL]
# 	2 : MaximumProbability [NUMERICAL]
#
# Attribute in nodes with depth <= 1:
# 	185 : Autocorrelation [NUMERICAL]
# 	148 : JointAverage [NUMERICAL]
# 	133 : SumAverage [NUMERICAL]
# 	60 : JointEnergy [NUMERICAL]
# 	55 : SumEntropy [NUMERICAL]
# 	49 : Correlation [NUMERICAL]
# 	44 : Imc2 [NUMERICAL]
# 	40 : Imc1 [NUMERICAL]
# 	34 : JointEntropy [NUMERICAL]
# 	28 : MaximumProbability [NUMERICAL]
# 	20 : Idm [NUMERICAL]
# 	17 : MCC [NUMERICAL]
# 	16 : ClusterTendency [NUMERICAL]
# 	14 : ClusterProminence [NUMERICAL]
# 	9 : Contrast [NUMERICAL]
# 	8 : Id [NUMERICAL]
# 	8 : ClusterShade [NUMERICAL]
# 	6 : DifferenceVariance [NUMERICAL]
# 	4 : InverseVariance [NUMERICAL]
# 	2 : SumSquares [NUMERICAL]
# 	2 : DifferenceEntropy [NUMERICAL]
# 	1 : Idn [NUMERICAL]
# 	1 : Idmn [NUMERICAL]
# 	1 : DifferenceAverage [NUMERICAL]
#
# Attribute in nodes with depth <= 2:
# 	296 : Autocorrelation [NUMERICAL]
# 	259 : SumAverage [NUMERICAL]
# 	256 : JointAverage [NUMERICAL]
# 	129 : Correlation [NUMERICAL]
# 	117 : SumEntropy [NUMERICAL]
# 	104 : Imc1 [NUMERICAL]
# 	103 : Imc2 [NUMERICAL]
# 	83 : JointEnergy [NUMERICAL]
# 	56 : JointEntropy [NUMERICAL]
# 	52 : MaximumProbability [NUMERICAL]
# 	49 : MCC [NUMERICAL]
# 	45 : ClusterTendency [NUMERICAL]
# 	37 : Idm [NUMERICAL]
# 	35 : ClusterProminence [NUMERICAL]
# 	28 : ClusterShade [NUMERICAL]
# 	26 : Id [NUMERICAL]
# 	26 : DifferenceVariance [NUMERICAL]
# 	22 : SumSquares [NUMERICAL]
# 	22 : InverseVariance [NUMERICAL]
# 	20 : Contrast [NUMERICAL]
# 	17 : DifferenceEntropy [NUMERICAL]
# 	16 : Idmn [NUMERICAL]
# 	14 : Idn [NUMERICAL]
# 	12 : DifferenceAverage [NUMERICAL]
#
# Attribute in nodes with depth <= 3:
# 	395 : Autocorrelation [NUMERICAL]
# 	363 : SumAverage [NUMERICAL]
# 	349 : JointAverage [NUMERICAL]
# 	219 : Correlation [NUMERICAL]
# 	178 : SumEntropy [NUMERICAL]
# 	166 : Imc2 [NUMERICAL]
# 	159 : Imc1 [NUMERICAL]
# 	115 : JointEnergy [NUMERICAL]
# 	99 : ClusterShade [NUMERICAL]
# 	89 : JointEntropy [NUMERICAL]
# 	83 : MaximumProbability [NUMERICAL]
# 	77 : MCC [NUMERICAL]
# 	72 : ClusterTendency [NUMERICAL]
# 	68 : DifferenceVariance [NUMERICAL]
# 	61 : Idm [NUMERICAL]
# 	57 : Contrast [NUMERICAL]
# 	54 : ClusterProminence [NUMERICAL]
# 	53 : Idn [NUMERICAL]
# 	52 : InverseVariance [NUMERICAL]
# 	49 : Id [NUMERICAL]
# 	42 : SumSquares [NUMERICAL]
# 	39 : Idmn [NUMERICAL]
# 	38 : DifferenceEntropy [NUMERICAL]
# 	36 : DifferenceAverage [NUMERICAL]
#
# Attribute in nodes with depth <= 5:
# 	505 : Autocorrelation [NUMERICAL]
# 	474 : SumAverage [NUMERICAL]
# 	453 : JointAverage [NUMERICAL]
# 	312 : Correlation [NUMERICAL]
# 	274 : SumEntropy [NUMERICAL]
# 	252 : Imc2 [NUMERICAL]
# 	252 : Imc1 [NUMERICAL]
# 	251 : ClusterShade [NUMERICAL]
# 	174 : JointEnergy [NUMERICAL]
# 	159 : DifferenceVariance [NUMERICAL]
# 	152 : JointEntropy [NUMERICAL]
# 	143 : MaximumProbability [NUMERICAL]
# 	138 : MCC [NUMERICAL]
# 	120 : Idm [NUMERICAL]
# 	119 : ClusterProminence [NUMERICAL]
# 	110 : Contrast [NUMERICAL]
# 	110 : ClusterTendency [NUMERICAL]
# 	104 : Idn [NUMERICAL]
# 	98 : InverseVariance [NUMERICAL]
# 	98 : Id [NUMERICAL]
# 	93 : SumSquares [NUMERICAL]
# 	92 : Idmn [NUMERICAL]
# 	88 : DifferenceEntropy [NUMERICAL]
# 	85 : DifferenceAverage [NUMERICAL]
#
# Condition type in nodes:
# 	5759 : HigherCondition
# Condition type in nodes with depth <= 0:
# 	300 : HigherCondition
# Condition type in nodes with depth <= 1:
# 	885 : HigherCondition
# Condition type in nodes with depth <= 2:
# 	1824 : HigherCondition
# Condition type in nodes with depth <= 3:
# 	2913 : HigherCondition
# Condition type in nodes with depth <= 5:
# 	4656 : HigherCondition
# Node format: NOT_SET
#
# Training OOB:
# 	trees: 1, Out-of-bag evaluation: accuracy:0.965304 logloss:1.25055
# 	trees: 11, Out-of-bag evaluation: accuracy:0.954742 logloss:1.27833
# 	trees: 21, Out-of-bag evaluation: accuracy:0.963303 logloss:0.283486
# 	trees: 31, Out-of-bag evaluation: accuracy:0.966329 logloss:0.17996
# 	trees: 41, Out-of-bag evaluation: accuracy:0.966168 logloss:0.176498
# 	trees: 51, Out-of-bag evaluation: accuracy:0.966168 logloss:0.0874573
# 	trees: 61, Out-of-bag evaluation: accuracy:0.971244 logloss:0.0816519
# 	trees: 71, Out-of-bag evaluation: accuracy:0.973622 logloss:0.0842784
# 	trees: 81, Out-of-bag evaluation: accuracy:0.973622 logloss:0.0866194
# 	trees: 91, Out-of-bag evaluation: accuracy:0.971244 logloss:0.0884839
# 	trees: 101, Out-of-bag evaluation: accuracy:0.973782 logloss:0.088836
# 	trees: 111, Out-of-bag evaluation: accuracy:0.971405 logloss:0.0893842
# 	trees: 121, Out-of-bag evaluation: accuracy:0.973782 logloss:0.090362
# 	trees: 131, Out-of-bag evaluation: accuracy:0.971405 logloss:0.0882022
# 	trees: 141, Out-of-bag evaluation: accuracy:0.971405 logloss:0.0871548
# 	trees: 151, Out-of-bag evaluation: accuracy:0.971566 logloss:0.0885997
# 	trees: 161, Out-of-bag evaluation: accuracy:0.971566 logloss:0.088482
# 	trees: 171, Out-of-bag evaluation: accuracy:0.971405 logloss:0.0884605
# 	trees: 181, Out-of-bag evaluation: accuracy:0.971405 logloss:0.0876973
# 	trees: 191, Out-of-bag evaluation: accuracy:0.971405 logloss:0.0873601
# 	trees: 201, Out-of-bag evaluation: accuracy:0.971405 logloss:0.0883441
# 	trees: 211, Out-of-bag evaluation: accuracy:0.971405 logloss:0.0885092
# 	trees: 221, Out-of-bag evaluation: accuracy:0.971405 logloss:0.0881044
# 	trees: 231, Out-of-bag evaluation: accuracy:0.971405 logloss:0.0876125
# 	trees: 241, Out-of-bag evaluation: accuracy:0.971405 logloss:0.0870964
# 	trees: 251, Out-of-bag evaluation: accuracy:0.973943 logloss:0.0873315
# 	trees: 261, Out-of-bag evaluation: accuracy:0.973943 logloss:0.0874623
# 	trees: 271, Out-of-bag evaluation: accuracy:0.973943 logloss:0.087176
# 	trees: 281, Out-of-bag evaluation: accuracy:0.971405 logloss:0.0866385
# 	trees: 291, Out-of-bag evaluation: accuracy:0.973943 logloss:0.0864598
# 	trees: 300, Out-of-bag evaluation: accuracy:0.971405 logloss:0.0864186

# %%
# Model features
model.make_inspector().features()
# Out:
# ["Autocorrelation" (1; #0),
#  "ClusterProminence" (1; #1),
#  "ClusterShade" (1; #2),
#  "ClusterTendency" (1; #3),
#  "Contrast" (1; #4),
#  "Correlation" (1; #5),
#  "DifferenceAverage" (1; #6),
#  "DifferenceEntropy" (1; #7),
#  "DifferenceVariance" (1; #8),
#  "Id" (1; #9),
#  "Idm" (1; #10),
#  "Idmn" (1; #11),
#  "Idn" (1; #12),
#  "Imc1" (1; #13),
#  "Imc2" (1; #14),
#  "InverseVariance" (1; #15),
#  "JointAverage" (1; #16),
#  "JointEnergy" (1; #17),
#  "JointEntropy" (1; #18),
#  "MCC" (1; #19),
#  "MaximumProbability" (1; #20),
#  "SumAverage" (1; #21),
#  "SumEntropy" (1; #22),
#  "SumSquares" (1; #23)]

# %%
# Feature importance
model.make_inspector().variable_importances()
# Out:
# {'INV_MEAN_MIN_DEPTH': [("Autocorrelation" (1; #0), 0.2633525079475913),
#   ("JointAverage" (1; #16), 0.2398129158428975),
#   ("SumAverage" (1; #21), 0.23728560183105302),
#   ("Correlation" (1; #5), 0.19409714211078413),
#   ("SumEntropy" (1; #22), 0.1875370065384233),
#   ("Imc1" (1; #13), 0.18629039782148982),
#   ("Imc2" (1; #14), 0.18357606588007871),
#   ("JointEnergy" (1; #17), 0.18219352079249845),
#   ("JointEntropy" (1; #18), 0.1736316550713689),
#   ("ClusterShade" (1; #2), 0.17318117908542832),
#   ("MCC" (1; #19), 0.17137704712148666),
#   ("ClusterProminence" (1; #1), 0.17121424913403546),
#   ("ClusterTendency" (1; #3), 0.16890135848310786),
#   ("DifferenceVariance" (1; #8), 0.1686581456124835),
#   ("MaximumProbability" (1; #20), 0.16835024818777866),
#   ("Idm" (1; #10), 0.1677163369514833),
#   ("Contrast" (1; #4), 0.16530697314126908),
#   ("Idmn" (1; #11), 0.16410557093646086),
#   ("Id" (1; #9), 0.1637646425493039),
#   ("DifferenceEntropy" (1; #7), 0.1628263238154954),
#   ("Idn" (1; #12), 0.1625131740452412),
#   ("SumSquares" (1; #23), 0.16234014751543693),
#   ("InverseVariance" (1; #15), 0.16204358225149937),
#   ("DifferenceAverage" (1; #6), 0.1619279315069166)],
#  'NUM_AS_ROOT': [("Autocorrelation" (1; #0), 90.0),
#   ("JointAverage" (1; #16), 56.0),
#   ("SumAverage" (1; #21), 55.0),
#   ("JointEnergy" (1; #17), 22.0),
#   ("SumEntropy" (1; #22), 21.0),
#   ("JointEntropy" (1; #18), 12.0),
#   ("Imc1" (1; #13), 11.0),
#   ("Idm" (1; #10), 8.0),
#   ("Imc2" (1; #14), 8.0),
#   ("ClusterProminence" (1; #1), 7.0),
#   ("ClusterTendency" (1; #3), 4.0),
#   ("Id" (1; #9), 4.0),
#   ("MaximumProbability" (1; #20), 2.0)],
#  'SUM_SCORE': [("Autocorrelation" (1; #0), 214065.6817118942),
#   ("SumAverage" (1; #21), 159211.00980820507),
#   ("JointAverage" (1; #16), 157744.6705927181),
#   ("SumEntropy" (1; #22), 21100.61500685124),
#   ("Imc2" (1; #14), 16103.334539243904),
#   ("JointEnergy" (1; #17), 16012.657467526866),
#   ("Correlation" (1; #5), 13515.463786331702),
#   ("Imc1" (1; #13), 13356.836254190906),
#   ("JointEntropy" (1; #18), 10981.821332620153),
#   ("MaximumProbability" (1; #20), 6786.125450005574),
#   ("ClusterShade" (1; #2), 5935.37116965375),
#   ("Idm" (1; #10), 5732.582225346149),
#   ("ClusterTendency" (1; #3), 5036.10628935132),
#   ("ClusterProminence" (1; #1), 4861.905992885793),
#   ("MCC" (1; #19), 4617.300058103216),
#   ("DifferenceVariance" (1; #8), 3404.4744897796636),
#   ("Id" (1; #9), 3325.665889627147),
#   ("InverseVariance" (1; #15), 2819.3475619568494),
#   ("Contrast" (1; #4), 2650.7469055216698),
#   ("SumSquares" (1; #23), 2569.4190280936855),
#   ("Idmn" (1; #11), 2207.7906953512943),
#   ("Idn" (1; #12), 1881.634548699357),
#   ("DifferenceEntropy" (1; #7), 1782.1063486164487),
#   ("DifferenceAverage" (1; #6), 1527.3633743304563)],
#  'NUM_NODES': [("Autocorrelation" (1; #0), 552.0),
#   ("SumAverage" (1; #21), 519.0),
#   ("JointAverage" (1; #16), 500.0),
#   ("Correlation" (1; #5), 365.0),
#   ("SumEntropy" (1; #22), 332.0),
#   ("ClusterShade" (1; #2), 317.0),
#   ("Imc2" (1; #14), 308.0),
#   ("Imc1" (1; #13), 301.0),
#   ("JointEnergy" (1; #17), 230.0),
#   ("DifferenceVariance" (1; #8), 206.0),
#   ("JointEntropy" (1; #18), 200.0),
#   ("MaximumProbability" (1; #20), 192.0),
#   ("MCC" (1; #19), 179.0),
#   ("Idm" (1; #10), 172.0),
#   ("ClusterProminence" (1; #1), 160.0),
#   ("Contrast" (1; #4), 152.0),
#   ("ClusterTendency" (1; #3), 149.0),
#   ("Id" (1; #9), 149.0),
#   ("Idn" (1; #12), 146.0),
#   ("InverseVariance" (1; #15), 142.0),
#   ("Idmn" (1; #11), 128.0),
#   ("SumSquares" (1; #23), 126.0),
#   ("DifferenceEntropy" (1; #7), 119.0),
#   ("DifferenceAverage" (1; #6), 115.0)]}

# %%
# Model self evaluation
model.make_inspector().evaluation()
# Out:
# Evaluation(num_examples=3308, accuracy=0.9714048895870537, loss=0.08641856436167415, rmse=None, ndcg=None, aucs=None, auuc=None, qini=None)

# %%
logs = model.make_inspector().training_logs()

plt.figure(figsize=(12, 4))
plt.subplot(1, 2, 1)
plt.plot([log.num_trees for log in logs], [log.evaluation.accuracy for log in logs])
plt.xlabel("Number of trees")
plt.ylabel("Accuracy (out-of-bag)")
plt.subplot(1, 2, 2)
plt.plot([log.num_trees for log in logs], [log.evaluation.loss for log in logs])
plt.xlabel("Number of trees")
plt.ylabel("Logloss (out-of-bag)")
plt.show()

# %% [markdown]
# Calculate the score of our hold-out validation dataset

# %%
predictions = model.predict(val_ds)
y_true      = validation_data["label"]

from sklearn.metrics import roc_auc_score
ROC_AUC = roc_auc_score(y_true, predictions)
print("The ROC AUC score is %.5f" % ROC_AUC )
# Out:
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 64ms/step
# The ROC AUC score is 0.97887

# %%
# Compute binary classification metrics with sklearn
import numpy as np
from sklearn.metrics import (
    accuracy_score,
    precision_score,
    recall_score,
    f1_score,
    roc_auc_score,
    average_precision_score,
    confusion_matrix,
    classification_report,
    matthews_corrcoef,
    log_loss,
    brier_score_loss,
)

# Get predictions (probabilities or class labels)
preds = model.predict(test_ds)
# If model outputs probabilities, convert to labels by threshold 0.5
if preds.ndim == 2:
    # For TFDF classification, preds may be class probabilities with shape (N, 2)
    if preds.shape[1] == 2:
        pos_probs = preds[:, 1]
    else:
        # If single-probability column (positive class)
        pos_probs = preds[:, -1]
    y_pred = (pos_probs >= 0.5).astype(int)
else:
    # Already class labels
    y_pred = preds.astype(int)
    pos_probs = None

# Ground truth labels (must be 0/1 integers)
y_true = test_data["label"].astype(int).to_numpy()

# Core metrics
metrics = {}
metrics["accuracy"] = accuracy_score(y_true, y_pred)
metrics["precision"] = precision_score(y_true, y_pred, zero_division=0)
metrics["recall"] = recall_score(y_true, y_pred, zero_division=0)
metrics["f1"] = f1_score(y_true, y_pred, zero_division=0)
metrics["mcc"] = matthews_corrcoef(y_true, y_pred)

# Probabilistic metrics (only if we have probabilities)
if pos_probs is not None:
    metrics["roc_auc"] = roc_auc_score(y_true, pos_probs)
    metrics["pr_auc"] = average_precision_score(y_true, pos_probs)
    metrics["log_loss"] = log_loss(y_true, pos_probs, labels=[0,1])
    metrics["brier_score"] = brier_score_loss(y_true, pos_probs)

# Confusion matrix and detailed report
cm = confusion_matrix(y_true, y_pred, labels=[0,1])
report = classification_report(y_true, y_pred, digits=4)

print("Sklearn binary metrics:")
for k, v in metrics.items():
    print(f"{k}: {v:.4f}")
print("\nConfusion matrix:\n", cm)
print("\nClassification report:\n", report)
# Out:
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 75ms/step
# Sklearn binary metrics:
# accuracy: 0.9915
# precision: 0.9259
# recall: 0.9259
# f1: 0.9259
# mcc: 0.9214
# roc_auc: 0.9939
# pr_auc: 0.9607
# log_loss: 0.0296
# brier_score: 0.0064
#
# Confusion matrix:
#  [[888   4]
#  [  4  50]]
#
# Classification report:
#                precision    recall  f1-score   support
#
#            0     0.9955    0.9955    0.9955       892
#            1     0.9259    0.9259    0.9259        54
#
#     accuracy                         0.9915       946
#    macro avg     0.9607    0.9607    0.9607       946
# weighted avg     0.9915    0.9915    0.9915       946
