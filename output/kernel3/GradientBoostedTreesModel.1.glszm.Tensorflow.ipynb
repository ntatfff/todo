# %%
# Import packages and modules
import numpy  as np
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow_decision_forests as tfdf

from sklearn.model_selection import train_test_split
# Out:
# 2026-08-15 04:56:49.217970: I tensorflow/core/util/port.cc:113] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2026-08-15 04:56:49.633875: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2026-08-15 04:56:54.588845: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
# Check the version of TensorFlow Decision Forests
print("Found TensorFlow Decision Forests v" + tfdf.__version__)
# Out:
# Found TensorFlow Decision Forests v1.9.1

# %%
datasetPath = 'dataset/firstorder/kernel5/dataset.csv'

# %%
# Parameters
datasetPath = "dataset/glszm/kernel3/1.dataset.csv"

# %%
# train/validation/test = 70/10/20
dataset = pd.read_csv(datasetPath)

train_data, temp_data = train_test_split(dataset, test_size=0.3, random_state=42)
validation_data, test_data = train_test_split(temp_data, test_size=2/3, random_state=42)

# %%
from sklearn.utils.class_weight import compute_class_weight

# tinh class weight tren tap train
classes = np.array([0, 1])
weights = compute_class_weight(class_weight="balanced", classes=classes, y=train_data["label"])
class_weight = {0: weights[0], 1: weights[1]}

# gan sample_weight cho tung dong
train_data["sample_weight"] = train_data["label"].map(class_weight)
validation_data["sample_weight"] = validation_data["label"].map(class_weight)
test_data["sample_weight"] = test_data["label"].map(class_weight)

# Convert the dataset into a TensorFlow dataset.
train_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    train_data, label="label", weight="sample_weight"
)         
val_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    validation_data, label="label", weight="sample_weight"
)
test_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    test_data, label="label", weight="sample_weight"
)
# Out:
# 2026-08-15 04:57:07.828935: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:984] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2026-08-15 04:57:07.830538: W tensorflow/core/common_runtime/gpu/gpu_device.cc:2251] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...

# %%
import keras

# %%
# %%time

# Train a Gradient Boosted Trees model.
model = tfdf.keras.GradientBoostedTreesModel()

# Add evaluation metrics
model.compile(
    metrics=["accuracy"]
)
model.fit(x=train_ds)

# # Train a Gradient Boosted Trees model.
# model = tfdf.keras.GradientBoostedTreesModel(num_trees=1500)
# model.fit(train_ds)
# Out:
# Use /tmp/tmpwetkd992 as temporary training directory
# Reading training dataset...
# [WARNING 26-08-15 04:57:07.9823 UTC gradient_boosted_trees.cc:1840] "goss_alpha" set but "sampling_method" not equal to "GOSS".
# [WARNING 26-08-15 04:57:07.9825 UTC gradient_boosted_trees.cc:1851] "goss_beta" set but "sampling_method" not equal to "GOSS".
# [WARNING 26-08-15 04:57:07.9825 UTC gradient_boosted_trees.cc:1865] "selective_gradient_boosting_ratio" set but "sampling_method" not equal to "SELGB".
# Training dataset read in 0:00:03.223161. Found 3308 examples.
# Training model...
# Model trained in 0:00:00.315153
# Compiling model...
# [INFO 26-08-15 04:57:11.5508 UTC kernel.cc:1233] Loading model from path /tmp/tmpwetkd992/model/ with prefix 48a8296dc3b04b66
# [INFO 26-08-15 04:57:11.5531 UTC quick_scorer_extended.cc:911] The binary was compiled without AVX2 support, but your CPU supports it. Enable it for faster model inference.
# [INFO 26-08-15 04:57:11.5532 UTC abstract_model.cc:1362] Engine "GradientBoostedTreesQuickScorerExtended" built
# [INFO 26-08-15 04:57:11.5532 UTC kernel.cc:1061] Use fast generic engine
# Model compiled.
# CPU times: user 6.35 s, sys: 348 ms, total: 6.7 s
# Wall time: 6.8 s

# %%
# Evaluate the model
evaluate = model.evaluate(val_ds, return_dict=True)
print()

for name, value in evaluate.items():
    print(f"{name}: {value:.4f}")
# Out:
# WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 1/1 [==============================] - ETA: 0s - loss: 0.0000e+00 - accuracy: 0.9958
# 1/1 [==============================] - 3s 3s/step - loss: 0.0000e+00 - accuracy: 0.9958
# loss: 0.0000
# accuracy: 0.9958

# %%
# Model Summary
model.summary()
# Out:
# Model: "gradient_boosted_trees_model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
# =================================================================
# Total params: 1 (1.00 Byte)
# Trainable params: 0 (0.00 Byte)
# Non-trainable params: 1 (1.00 Byte)
# _________________________________________________________________
# Type: "GRADIENT_BOOSTED_TREES"
# Task: CLASSIFICATION
# Label: "__LABEL"
#
# Input Features (16):
# 	GrayLevelNonUniformity
# 	GrayLevelNonUniformityNormalized
# 	GrayLevelVariance
# 	HighGrayLevelZoneEmphasis
# 	LargeAreaEmphasis
# 	LargeAreaHighGrayLevelEmphasis
# 	LargeAreaLowGrayLevelEmphasis
# 	LowGrayLevelZoneEmphasis
# 	SizeZoneNonUniformity
# 	SizeZoneNonUniformityNormalized
# 	SmallAreaEmphasis
# 	SmallAreaHighGrayLevelEmphasis
# 	SmallAreaLowGrayLevelEmphasis
# 	ZoneEntropy
# 	ZonePercentage
# 	ZoneVariance
#
# Trained with weights
#
# Variable Importance: INV_MEAN_MIN_DEPTH:
#     1.   "SmallAreaHighGrayLevelEmphasis"  0.665044 ################
#     2.                      "ZoneEntropy"  0.313319 ####
#     3.        "HighGrayLevelZoneEmphasis"  0.283631 ###
#     4.    "LargeAreaLowGrayLevelEmphasis"  0.222207 #
#     5.         "LowGrayLevelZoneEmphasis"  0.204578
#     6.           "GrayLevelNonUniformity"  0.201107
#     7.                "GrayLevelVariance"  0.184819
#     8.   "LargeAreaHighGrayLevelEmphasis"  0.184574
#     9.                     "ZoneVariance"  0.182452
#    10. "GrayLevelNonUniformityNormalized"  0.180148
#    11.    "SmallAreaLowGrayLevelEmphasis"  0.178305
#    12.                "LargeAreaEmphasis"  0.178121
#    13.  "SizeZoneNonUniformityNormalized"  0.177868
#    14.                   "ZonePercentage"  0.177506
#    15.            "SizeZoneNonUniformity"  0.177342
#    16.                "SmallAreaEmphasis"  0.177127
#
# Variable Importance: NUM_AS_ROOT:
#     1. "SmallAreaHighGrayLevelEmphasis" 20.000000 ################
#     2.      "HighGrayLevelZoneEmphasis"  5.000000
#
# Variable Importance: NUM_NODES:
#     1.   "SmallAreaHighGrayLevelEmphasis" 78.000000 ################
#     2.    "LargeAreaLowGrayLevelEmphasis" 69.000000 ##############
#     3.           "GrayLevelNonUniformity" 68.000000 #############
#     4.        "HighGrayLevelZoneEmphasis" 62.000000 ############
#     5.         "LowGrayLevelZoneEmphasis" 62.000000 ############
#     6.                      "ZoneEntropy" 56.000000 ###########
#     7.   "LargeAreaHighGrayLevelEmphasis" 35.000000 ######
#     8.                "GrayLevelVariance" 24.000000 ####
#     9.                     "ZoneVariance" 22.000000 ####
#    10. "GrayLevelNonUniformityNormalized" 18.000000 ###
#    11.    "SmallAreaLowGrayLevelEmphasis" 14.000000 ##
#    12.  "SizeZoneNonUniformityNormalized" 10.000000 #
#    13.                "LargeAreaEmphasis"  7.000000
#    14.            "SizeZoneNonUniformity"  5.000000
#    15.                   "ZonePercentage"  5.000000
#    16.                "SmallAreaEmphasis"  3.000000
#
# Variable Importance: SUM_SCORE:
#     1.   "SmallAreaHighGrayLevelEmphasis" 3136.558181 ################
#     2.                      "ZoneEntropy" 288.978099 #
#     3.        "HighGrayLevelZoneEmphasis" 117.627798
#     4.           "GrayLevelNonUniformity" 103.337726
#     5.    "LargeAreaLowGrayLevelEmphasis" 90.604957
#     6.         "LowGrayLevelZoneEmphasis" 85.797269
#     7.    "SmallAreaLowGrayLevelEmphasis" 24.510482
#     8.   "LargeAreaHighGrayLevelEmphasis" 15.499855
#     9.                     "ZoneVariance" 15.188996
#    10.                "GrayLevelVariance" 12.776634
#    11. "GrayLevelNonUniformityNormalized"  6.861543
#    12.            "SizeZoneNonUniformity"  6.609798
#    13.                   "ZonePercentage"  2.720829
#    14.  "SizeZoneNonUniformityNormalized"  0.355586
#    15.                "SmallAreaEmphasis"  0.054649
#    16.                "LargeAreaEmphasis"  0.049375
#
#
#
# Loss: BINOMIAL_LOG_LIKELIHOOD
# Validation loss value: 0.380013
# Number of trees per iteration: 1
# Node format: NOT_SET
# Number of trees: 25
# Total number of nodes: 1101
#
# Number of nodes by tree:
# Count: 25 Average: 44.04 StdDev: 5.15736
# Min: 33 Max: 49 Ignored: 0
# ----------------------------------------------
# [ 33, 34) 1   4.00%   4.00% ##
# [ 34, 35) 0   0.00%   4.00%
# [ 35, 36) 4  16.00%  20.00% #######
# [ 36, 37) 0   0.00%  20.00%
# [ 37, 38) 0   0.00%  20.00%
# [ 38, 39) 0   0.00%  20.00%
# [ 39, 40) 0   0.00%  20.00%
# [ 40, 41) 0   0.00%  20.00%
# [ 41, 42) 1   4.00%  24.00% ##
# [ 42, 43) 0   0.00%  24.00%
# [ 43, 44) 2   8.00%  32.00% ###
# [ 44, 45) 0   0.00%  32.00%
# [ 45, 46) 5  20.00%  52.00% ########
# [ 46, 47) 0   0.00%  52.00%
# [ 47, 48) 6  24.00%  76.00% ##########
# [ 48, 49) 0   0.00%  76.00%
# [ 49, 49] 6  24.00% 100.00% ##########
#
# Depth by leafs:
# Count: 563 Average: 4.66607 StdDev: 0.615406
# Min: 2 Max: 5 Ignored: 0
# ----------------------------------------------
# [ 2, 3)   5   0.89%   0.89%
# [ 3, 4)  29   5.15%   6.04% #
# [ 4, 5) 115  20.43%  26.47% ###
# [ 5, 5] 414  73.53% 100.00% ##########
#
# Number of training obs by leaf:
# Count: 563 Average: 132.815 StdDev: 476.821
# Min: 5 Max: 2456 Ignored: 0
# ----------------------------------------------
# [    5,  127) 488  86.68%  86.68% ##########
# [  127,  250)  47   8.35%  95.03% #
# [  250,  372)   1   0.18%  95.20%
# [  372,  495)   1   0.18%  95.38%
# [  495,  618)   0   0.00%  95.38%
# [  618,  740)   0   0.00%  95.38%
# [  740,  863)   1   0.18%  95.56%
# [  863,  985)   0   0.00%  95.56%
# [  985, 1108)   0   0.00%  95.56%
# [ 1108, 1231)   0   0.00%  95.56%
# [ 1231, 1353)   0   0.00%  95.56%
# [ 1353, 1476)   0   0.00%  95.56%
# [ 1476, 1598)   0   0.00%  95.56%
# [ 1598, 1721)   1   0.18%  95.74%
# [ 1721, 1844)   0   0.00%  95.74%
# [ 1844, 1966)   0   0.00%  95.74%
# [ 1966, 2089)   1   0.18%  95.91%
# [ 2089, 2211)   1   0.18%  96.09%
# [ 2211, 2334)   6   1.07%  97.16%
# [ 2334, 2456]  16   2.84% 100.00%
#
# Attribute in nodes:
# 	78 : SmallAreaHighGrayLevelEmphasis [NUMERICAL]
# 	69 : LargeAreaLowGrayLevelEmphasis [NUMERICAL]
# 	68 : GrayLevelNonUniformity [NUMERICAL]
# 	62 : LowGrayLevelZoneEmphasis [NUMERICAL]
# 	62 : HighGrayLevelZoneEmphasis [NUMERICAL]
# 	56 : ZoneEntropy [NUMERICAL]
# 	35 : LargeAreaHighGrayLevelEmphasis [NUMERICAL]
# 	24 : GrayLevelVariance [NUMERICAL]
# 	22 : ZoneVariance [NUMERICAL]
# 	18 : GrayLevelNonUniformityNormalized [NUMERICAL]
# 	14 : SmallAreaLowGrayLevelEmphasis [NUMERICAL]
# 	10 : SizeZoneNonUniformityNormalized [NUMERICAL]
# 	7 : LargeAreaEmphasis [NUMERICAL]
# 	5 : ZonePercentage [NUMERICAL]
# 	5 : SizeZoneNonUniformity [NUMERICAL]
# 	3 : SmallAreaEmphasis [NUMERICAL]
#
# Attribute in nodes with depth <= 0:
# 	20 : SmallAreaHighGrayLevelEmphasis [NUMERICAL]
# 	5 : HighGrayLevelZoneEmphasis [NUMERICAL]
#
# Attribute in nodes with depth <= 1:
# 	27 : SmallAreaHighGrayLevelEmphasis [NUMERICAL]
# 	25 : ZoneEntropy [NUMERICAL]
# 	23 : HighGrayLevelZoneEmphasis [NUMERICAL]
#
# Attribute in nodes with depth <= 2:
# 	39 : SmallAreaHighGrayLevelEmphasis [NUMERICAL]
# 	36 : ZoneEntropy [NUMERICAL]
# 	29 : LowGrayLevelZoneEmphasis [NUMERICAL]
# 	29 : LargeAreaLowGrayLevelEmphasis [NUMERICAL]
# 	23 : HighGrayLevelZoneEmphasis [NUMERICAL]
# 	11 : GrayLevelNonUniformity [NUMERICAL]
# 	3 : LargeAreaHighGrayLevelEmphasis [NUMERICAL]
#
# Attribute in nodes with depth <= 3:
# 	61 : SmallAreaHighGrayLevelEmphasis [NUMERICAL]
# 	52 : LargeAreaLowGrayLevelEmphasis [NUMERICAL]
# 	45 : ZoneEntropy [NUMERICAL]
# 	39 : HighGrayLevelZoneEmphasis [NUMERICAL]
# 	35 : LowGrayLevelZoneEmphasis [NUMERICAL]
# 	34 : GrayLevelNonUniformity [NUMERICAL]
# 	18 : ZoneVariance [NUMERICAL]
# 	17 : GrayLevelVariance [NUMERICAL]
# 	14 : LargeAreaHighGrayLevelEmphasis [NUMERICAL]
# 	6 : GrayLevelNonUniformityNormalized [NUMERICAL]
# 	3 : LargeAreaEmphasis [NUMERICAL]
# 	2 : ZonePercentage [NUMERICAL]
# 	2 : SmallAreaLowGrayLevelEmphasis [NUMERICAL]
# 	1 : SmallAreaEmphasis [NUMERICAL]
# 	1 : SizeZoneNonUniformityNormalized [NUMERICAL]
# 	1 : SizeZoneNonUniformity [NUMERICAL]
#
# Attribute in nodes with depth <= 5:
# 	78 : SmallAreaHighGrayLevelEmphasis [NUMERICAL]
# 	69 : LargeAreaLowGrayLevelEmphasis [NUMERICAL]
# 	68 : GrayLevelNonUniformity [NUMERICAL]
# 	62 : LowGrayLevelZoneEmphasis [NUMERICAL]
# 	62 : HighGrayLevelZoneEmphasis [NUMERICAL]
# 	56 : ZoneEntropy [NUMERICAL]
# 	35 : LargeAreaHighGrayLevelEmphasis [NUMERICAL]
# 	24 : GrayLevelVariance [NUMERICAL]
# 	22 : ZoneVariance [NUMERICAL]
# 	18 : GrayLevelNonUniformityNormalized [NUMERICAL]
# 	14 : SmallAreaLowGrayLevelEmphasis [NUMERICAL]
# 	10 : SizeZoneNonUniformityNormalized [NUMERICAL]
# 	7 : LargeAreaEmphasis [NUMERICAL]
# 	5 : ZonePercentage [NUMERICAL]
# 	5 : SizeZoneNonUniformity [NUMERICAL]
# 	3 : SmallAreaEmphasis [NUMERICAL]
#
# Condition type in nodes:
# 	538 : HigherCondition
# Condition type in nodes with depth <= 0:
# 	25 : HigherCondition
# Condition type in nodes with depth <= 1:
# 	75 : HigherCondition
# Condition type in nodes with depth <= 2:
# 	170 : HigherCondition
# Condition type in nodes with depth <= 3:
# 	331 : HigherCondition
# Condition type in nodes with depth <= 5:
# 	538 : HigherCondition
#
# Training logs:
# Number of iteration to final model: 25
# 	Iter:1 train-loss:1.200270 valid-loss:1.222919  train-accuracy:0.993890 valid-accuracy:0.946052
# 	Iter:2 train-loss:1.048359 valid-loss:1.088724  train-accuracy:0.994429 valid-accuracy:0.947582
# 	Iter:3 train-loss:0.921285 valid-loss:0.978105  train-accuracy:0.994249 valid-accuracy:0.947582
# 	Iter:4 train-loss:0.813908 valid-loss:0.886474  train-accuracy:0.994429 valid-accuracy:0.947582
# 	Iter:5 train-loss:0.723091 valid-loss:0.802059  train-accuracy:0.994249 valid-accuracy:0.947582
# 	Iter:6 train-loss:0.643800 valid-loss:0.735781  train-accuracy:0.994429 valid-accuracy:0.947582
# 	Iter:16 train-loss:0.228768 valid-loss:0.434949  train-accuracy:0.995687 valid-accuracy:0.947582
# 	Iter:26 train-loss:0.094407 valid-loss:0.385915  train-accuracy:0.997484 valid-accuracy:0.949113
# 	Iter:36 train-loss:0.044424 valid-loss:0.421347  train-accuracy:0.998023 valid-accuracy:0.949113
# 	Iter:46 train-loss:0.025583 valid-loss:0.489815  train-accuracy:0.998383 valid-accuracy:0.926730

# %%
# Model features
model.make_inspector().features()
# Out:
# ["GrayLevelNonUniformity" (1; #0),
#  "GrayLevelNonUniformityNormalized" (1; #1),
#  "GrayLevelVariance" (1; #2),
#  "HighGrayLevelZoneEmphasis" (1; #3),
#  "LargeAreaEmphasis" (1; #4),
#  "LargeAreaHighGrayLevelEmphasis" (1; #5),
#  "LargeAreaLowGrayLevelEmphasis" (1; #6),
#  "LowGrayLevelZoneEmphasis" (1; #7),
#  "SizeZoneNonUniformity" (1; #8),
#  "SizeZoneNonUniformityNormalized" (1; #9),
#  "SmallAreaEmphasis" (1; #10),
#  "SmallAreaHighGrayLevelEmphasis" (1; #11),
#  "SmallAreaLowGrayLevelEmphasis" (1; #12),
#  "ZoneEntropy" (1; #13),
#  "ZonePercentage" (1; #14),
#  "ZoneVariance" (1; #15)]

# %%
# Feature importance
model.make_inspector().variable_importances()
# Out:
# {'INV_MEAN_MIN_DEPTH': [("SmallAreaHighGrayLevelEmphasis" (1; #11),
#    0.6650439015908893),
#   ("ZoneEntropy" (1; #13), 0.3133186072011506),
#   ("HighGrayLevelZoneEmphasis" (1; #3), 0.28363093637200915),
#   ("LargeAreaLowGrayLevelEmphasis" (1; #6), 0.22220699301472893),
#   ("LowGrayLevelZoneEmphasis" (1; #7), 0.20457761391508425),
#   ("GrayLevelNonUniformity" (1; #0), 0.20110699428612902),
#   ("GrayLevelVariance" (1; #2), 0.18481923768791905),
#   ("LargeAreaHighGrayLevelEmphasis" (1; #5), 0.18457381349941224),
#   ("ZoneVariance" (1; #15), 0.18245225878652394),
#   ("GrayLevelNonUniformityNormalized" (1; #1), 0.1801476913086367),
#   ("SmallAreaLowGrayLevelEmphasis" (1; #12), 0.17830539537719212),
#   ("LargeAreaEmphasis" (1; #4), 0.17812074217108168),
#   ("SizeZoneNonUniformityNormalized" (1; #9), 0.177867796966769),
#   ("ZonePercentage" (1; #14), 0.1775055822961584),
#   ("SizeZoneNonUniformity" (1; #8), 0.17734175798724278),
#   ("SmallAreaEmphasis" (1; #10), 0.1771273777799737)],
#  'NUM_AS_ROOT': [("SmallAreaHighGrayLevelEmphasis" (1; #11), 20.0),
#   ("HighGrayLevelZoneEmphasis" (1; #3), 5.0)],
#  'SUM_SCORE': [("SmallAreaHighGrayLevelEmphasis" (1; #11), 3136.558181269305),
#   ("ZoneEntropy" (1; #13), 288.97809926629486),
#   ("HighGrayLevelZoneEmphasis" (1; #3), 117.62779783217655),
#   ("GrayLevelNonUniformity" (1; #0), 103.33772588288451),
#   ("LargeAreaLowGrayLevelEmphasis" (1; #6), 90.60495721415245),
#   ("LowGrayLevelZoneEmphasis" (1; #7), 85.7972694695447),
#   ("SmallAreaLowGrayLevelEmphasis" (1; #12), 24.510482446038473),
#   ("LargeAreaHighGrayLevelEmphasis" (1; #5), 15.499854546887137),
#   ("ZoneVariance" (1; #15), 15.188995537084953),
#   ("GrayLevelVariance" (1; #2), 12.77663359338963),
#   ("GrayLevelNonUniformityNormalized" (1; #1), 6.861542871770351),
#   ("SizeZoneNonUniformity" (1; #8), 6.609797895263954),
#   ("ZonePercentage" (1; #14), 2.720828825335684),
#   ("SizeZoneNonUniformityNormalized" (1; #9), 0.35558584602636684),
#   ("SmallAreaEmphasis" (1; #10), 0.05464923135164401),
#   ("LargeAreaEmphasis" (1; #4), 0.04937520390807855)],
#  'NUM_NODES': [("SmallAreaHighGrayLevelEmphasis" (1; #11), 78.0),
#   ("LargeAreaLowGrayLevelEmphasis" (1; #6), 69.0),
#   ("GrayLevelNonUniformity" (1; #0), 68.0),
#   ("HighGrayLevelZoneEmphasis" (1; #3), 62.0),
#   ("LowGrayLevelZoneEmphasis" (1; #7), 62.0),
#   ("ZoneEntropy" (1; #13), 56.0),
#   ("LargeAreaHighGrayLevelEmphasis" (1; #5), 35.0),
#   ("GrayLevelVariance" (1; #2), 24.0),
#   ("ZoneVariance" (1; #15), 22.0),
#   ("GrayLevelNonUniformityNormalized" (1; #1), 18.0),
#   ("SmallAreaLowGrayLevelEmphasis" (1; #12), 14.0),
#   ("SizeZoneNonUniformityNormalized" (1; #9), 10.0),
#   ("LargeAreaEmphasis" (1; #4), 7.0),
#   ("SizeZoneNonUniformity" (1; #8), 5.0),
#   ("ZonePercentage" (1; #14), 5.0),
#   ("SmallAreaEmphasis" (1; #10), 3.0)]}

# %%
# Model self evaluation
model.make_inspector().evaluation()
# Out:
# Evaluation(num_examples=None, accuracy=0.9491127729415894, loss=0.38001328706741333, rmse=None, ndcg=None, aucs=None, auuc=None, qini=None)

# %%
logs = model.make_inspector().training_logs()

plt.figure(figsize=(12, 4))
plt.subplot(1, 2, 1)
plt.plot([log.num_trees for log in logs], [log.evaluation.accuracy for log in logs])
plt.xlabel("Number of trees")
plt.ylabel("Accuracy (out-of-bag)")
plt.subplot(1, 2, 2)
plt.plot([log.num_trees for log in logs], [log.evaluation.loss for log in logs])
plt.xlabel("Number of trees")
plt.ylabel("Logloss (out-of-bag)")
plt.show()

# %% [markdown]
# Calculate the score of our hold-out validation dataset

# %%
predictions = model.predict(val_ds)
y_true      = validation_data["label"]

from sklearn.metrics import roc_auc_score
ROC_AUC = roc_auc_score(y_true, predictions)
print("The ROC AUC score is %.5f" % ROC_AUC )
# Out:
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 60ms/step
# The ROC AUC score is 0.99977

# %%
# Compute binary classification metrics with sklearn
import numpy as np
from sklearn.metrics import (
    accuracy_score,
    precision_score,
    recall_score,
    f1_score,
    roc_auc_score,
    average_precision_score,
    confusion_matrix,
    classification_report,
    matthews_corrcoef,
    log_loss,
    brier_score_loss,
)

# Get predictions (probabilities or class labels)
preds = model.predict(test_ds)
# If model outputs probabilities, convert to labels by threshold 0.5
if preds.ndim == 2:
    # For TFDF classification, preds may be class probabilities with shape (N, 2)
    if preds.shape[1] == 2:
        pos_probs = preds[:, 1]
    else:
        # If single-probability column (positive class)
        pos_probs = preds[:, -1]
    y_pred = (pos_probs >= 0.5).astype(int)
else:
    # Already class labels
    y_pred = preds.astype(int)
    pos_probs = None

# Ground truth labels (must be 0/1 integers)
y_true = test_data["label"].astype(int).to_numpy()

# Core metrics
metrics = {}
metrics["accuracy"] = accuracy_score(y_true, y_pred)
metrics["precision"] = precision_score(y_true, y_pred, zero_division=0)
metrics["recall"] = recall_score(y_true, y_pred, zero_division=0)
metrics["f1"] = f1_score(y_true, y_pred, zero_division=0)
metrics["mcc"] = matthews_corrcoef(y_true, y_pred)

# Probabilistic metrics (only if we have probabilities)
if pos_probs is not None:
    metrics["roc_auc"] = roc_auc_score(y_true, pos_probs)
    metrics["pr_auc"] = average_precision_score(y_true, pos_probs)
    metrics["log_loss"] = log_loss(y_true, pos_probs, labels=[0,1])
    metrics["brier_score"] = brier_score_loss(y_true, pos_probs)

# Confusion matrix and detailed report
cm = confusion_matrix(y_true, y_pred, labels=[0,1])
report = classification_report(y_true, y_pred, digits=4)

print("Sklearn binary metrics:")
for k, v in metrics.items():
    print(f"{k}: {v:.4f}")
print("\nConfusion matrix:\n", cm)
print("\nClassification report:\n", report)
# Out:
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 68ms/step
# Sklearn binary metrics:
# accuracy: 0.9863
# precision: 0.8154
# recall: 0.9815
# f1: 0.8908
# mcc: 0.8878
# roc_auc: 0.9798
# pr_auc: 0.9343
# log_loss: 0.0737
# brier_score: 0.0122
#
# Confusion matrix:
#  [[880  12]
#  [  1  53]]
#
# Classification report:
#                precision    recall  f1-score   support
#
#            0     0.9989    0.9865    0.9927       892
#            1     0.8154    0.9815    0.8908        54
#
#     accuracy                         0.9863       946
#    macro avg     0.9071    0.9840    0.9417       946
# weighted avg     0.9884    0.9863    0.9869       946
