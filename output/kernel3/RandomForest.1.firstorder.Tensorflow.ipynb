# %%
# Import packages and modules
import numpy  as np
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow_decision_forests as tfdf

from sklearn.model_selection import train_test_split
# Out:
# 2026-08-15 05:09:04.214764: I tensorflow/core/util/port.cc:113] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2026-08-15 05:09:04.589047: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2026-08-15 05:09:09.379239: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
# Check the version of TensorFlow Decision Forests
print("Found TensorFlow Decision Forests v" + tfdf.__version__)
# Out:
# Found TensorFlow Decision Forests v1.9.1

# %%
datasetPath = 'dataset/firstorder/kernel5/dataset.csv'

# %%
# Parameters
datasetPath = "dataset/firstorder/kernel3/1.dataset.csv"

# %%
# train/validation/test = 70/10/20
dataset = pd.read_csv(datasetPath)

train_data, temp_data = train_test_split(dataset, test_size=0.3, random_state=42)
validation_data, test_data = train_test_split(temp_data, test_size=2/3, random_state=42)

# %%
from sklearn.utils.class_weight import compute_class_weight

# tinh class weight tren tap train
classes = np.array([0, 1])
weights = compute_class_weight(class_weight="balanced", classes=classes, y=train_data["label"])
class_weight = {0: weights[0], 1: weights[1]}

# gan sample_weight cho tung dong
train_data["sample_weight"] = train_data["label"].map(class_weight)
validation_data["sample_weight"] = validation_data["label"].map(class_weight)
test_data["sample_weight"] = test_data["label"].map(class_weight)

# Convert the dataset into a TensorFlow dataset.
train_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    train_data, label="label", weight="sample_weight"
)         
val_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    validation_data, label="label", weight="sample_weight"
)
test_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    test_data, label="label", weight="sample_weight"
)
# Out:
# 2026-08-15 05:09:22.479688: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:984] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2026-08-15 05:09:22.481426: W tensorflow/core/common_runtime/gpu/gpu_device.cc:2251] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...

# %%
import keras

# %%
# %%time

# Train a Random Forest model.
model = tfdf.keras.RandomForestModel()

# Add evaluation metrics
model.compile(
    metrics=["accuracy"]
)
model.fit(x=train_ds)

# # Train a Gradient Boosted Trees model.
# model = tfdf.keras.GradientBoostedTreesModel(num_trees=1500)
# model.fit(train_ds)
# Out:
# Use /tmp/tmpz1fvr0zz as temporary training directory
# Reading training dataset...
# Training dataset read in 0:00:03.344603. Found 3308 examples.
# Training model...
# Model trained in 0:00:00.132220
# Compiling model...
# [INFO 26-08-15 05:09:26.1202 UTC kernel.cc:1233] Loading model from path /tmp/tmpz1fvr0zz/model/ with prefix acbc76a1a6ee4d27
# [INFO 26-08-15 05:09:26.1365 UTC decision_forest.cc:734] Model loaded with 300 root(s), 11402 node(s), and 18 input feature(s).
# [INFO 26-08-15 05:09:26.1365 UTC abstract_model.cc:1362] Engine "RandomForestOptPred" built
# [INFO 26-08-15 05:09:26.1365 UTC kernel.cc:1061] Use fast generic engine
# Model compiled.
# CPU times: user 6.05 s, sys: 102 ms, total: 6.15 s
# Wall time: 6.66 s

# %%
# Evaluate the model
evaluate = model.evaluate(val_ds, return_dict=True)
print()

for name, value in evaluate.items():
    print(f"{name}: {value:.4f}")
# Out:
# WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 1/1 [==============================] - ETA: 0s - loss: 0.0000e+00 - accuracy: 0.9915
# 1/1 [==============================] - 3s 3s/step - loss: 0.0000e+00 - accuracy: 0.9915
# loss: 0.0000
# accuracy: 0.9915

# %%
# Model Summary
model.summary()
# Out:
# Model: "random_forest_model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
# =================================================================
# Total params: 1 (1.00 Byte)
# Trainable params: 0 (0.00 Byte)
# Non-trainable params: 1 (1.00 Byte)
# _________________________________________________________________
# Type: "RANDOM_FOREST"
# Task: CLASSIFICATION
# Label: "__LABEL"
#
# Input Features (18):
# 	10Percentile
# 	90Percentile
# 	Energy
# 	Entropy
# 	InterquartileRange
# 	Kurtosis
# 	Maximum
# 	Mean
# 	MeanAbsoluteDeviation
# 	Median
# 	Minimum
# 	Range
# 	RobustMeanAbsoluteDeviation
# 	RootMeanSquared
# 	Skewness
# 	TotalEnergy
# 	Uniformity
# 	Variance
#
# Trained with weights
#
# Variable Importance: INV_MEAN_MIN_DEPTH:
#     1.                "90Percentile"  0.290954 ################
#     2.                     "Maximum"  0.232395 ########
#     3.                 "TotalEnergy"  0.206563 #####
#     4.                      "Energy"  0.197446 ####
#     5.             "RootMeanSquared"  0.187694 ###
#     6.                  "Uniformity"  0.186567 ###
#     7.                     "Entropy"  0.181259 ##
#     8.                        "Mean"  0.180969 ##
#     9.                    "Skewness"  0.180834 ##
#    10.                     "Minimum"  0.177160 #
#    11.                      "Median"  0.169942 #
#    12.                "10Percentile"  0.169173
#    13.                       "Range"  0.168349
#    14.                    "Kurtosis"  0.166118
#    15. "RobustMeanAbsoluteDeviation"  0.165014
#    16.          "InterquartileRange"  0.163281
#    17.                    "Variance"  0.162291
#    18.       "MeanAbsoluteDeviation"  0.161714
#
# Variable Importance: NUM_AS_ROOT:
#     1.    "90Percentile" 85.000000 ################
#     2.         "Maximum" 72.000000 #############
#     3.     "TotalEnergy" 54.000000 #########
#     4.          "Energy" 35.000000 ######
#     5. "RootMeanSquared" 27.000000 ####
#     6.            "Mean" 14.000000 #
#     7.          "Median"  8.000000
#     8.    "10Percentile"  5.000000
#
# Variable Importance: NUM_NODES:
#     1.                "90Percentile" 586.000000 ################
#     2.                  "Uniformity" 416.000000 #########
#     3.                     "Maximum" 411.000000 #########
#     4.                    "Skewness" 389.000000 ########
#     5.                     "Entropy" 350.000000 ######
#     6.                     "Minimum" 350.000000 ######
#     7.                      "Energy" 321.000000 #####
#     8.                       "Range" 317.000000 #####
#     9.                 "TotalEnergy" 314.000000 #####
#    10.                        "Mean" 287.000000 ####
#    11.             "RootMeanSquared" 282.000000 ####
#    12.                    "Kurtosis" 269.000000 ###
#    13.                "10Percentile" 255.000000 ###
#    14.                      "Median" 251.000000 ##
#    15. "RobustMeanAbsoluteDeviation" 199.000000
#    16.       "MeanAbsoluteDeviation" 195.000000
#    17.          "InterquartileRange" 181.000000
#    18.                    "Variance" 178.000000
#
# Variable Importance: SUM_SCORE:
#     1.                "90Percentile" 195222.931342 ################
#     2.                     "Maximum" 150610.583636 ############
#     3.                 "TotalEnergy" 96811.478701 #######
#     4.                      "Energy" 66569.191147 #####
#     5.             "RootMeanSquared" 50050.706154 ###
#     6.                        "Mean" 28438.073354 ##
#     7.                      "Median" 15150.263559 #
#     8.                  "Uniformity" 14742.686463 #
#     9.                     "Entropy" 13879.038027
#    10.                "10Percentile" 9179.805112
#    11.                     "Minimum" 7663.347190
#    12.                    "Skewness" 7471.000178
#    13.                       "Range" 4760.482069
#    14. "RobustMeanAbsoluteDeviation" 4745.958364
#    15.          "InterquartileRange" 3936.243546
#    16.                    "Kurtosis" 3826.100697
#    17.       "MeanAbsoluteDeviation" 2951.184010
#    18.                    "Variance" 2141.565548
#
#
#
# Winner takes all: true
# Out-of-bag evaluation: accuracy:0.958888 logloss:0.175056
# Number of trees: 300
# Total number of nodes: 11402
#
# Number of nodes by tree:
# Count: 300 Average: 38.0067 StdDev: 4.70319
# Min: 25 Max: 51 Ignored: 0
# ----------------------------------------------
# [ 25, 26)  2   0.67%   0.67%
# [ 26, 27)  0   0.00%   0.67%
# [ 27, 29)  3   1.00%   1.67% #
# [ 29, 30)  8   2.67%   4.33% ##
# [ 30, 31)  0   0.00%   4.33%
# [ 31, 33) 20   6.67%  11.00% ####
# [ 33, 34) 22   7.33%  18.33% ####
# [ 34, 35)  0   0.00%  18.33%
# [ 35, 37) 47  15.67%  34.00% ##########
# [ 37, 38) 49  16.33%  50.33% ##########
# [ 38, 39)  0   0.00%  50.33%
# [ 39, 41) 45  15.00%  65.33% #########
# [ 41, 42) 45  15.00%  80.33% #########
# [ 42, 43)  0   0.00%  80.33%
# [ 43, 45) 28   9.33%  89.67% ######
# [ 45, 46) 17   5.67%  95.33% ###
# [ 46, 47)  0   0.00%  95.33%
# [ 47, 49) 11   3.67%  99.00% ##
# [ 49, 50)  2   0.67%  99.67%
# [ 50, 51]  1   0.33% 100.00%
#
# Depth by leafs:
# Count: 5851 Average: 5.54213 StdDev: 2.18759
# Min: 1 Max: 13 Ignored: 0
# ----------------------------------------------
# [  1,  2)  15   0.26%   0.26%
# [  2,  3) 310   5.30%   5.55% ###
# [  3,  4) 796  13.60%  19.16% ########
# [  4,  5) 991  16.94%  36.10% ##########
# [  5,  6) 967  16.53%  52.62% ##########
# [  6,  7) 964  16.48%  69.10% ##########
# [  7,  8) 707  12.08%  81.18% #######
# [  8,  9) 489   8.36%  89.54% #####
# [  9, 10) 321   5.49%  95.03% ###
# [ 10, 11) 184   3.14%  98.17% ##
# [ 11, 12)  69   1.18%  99.35% #
# [ 12, 13)  22   0.38%  99.73%
# [ 13, 13]  16   0.27% 100.00%
#
# Number of training obs by leaf:
# Count: 5851 Average: 169.612 StdDev: 584.042
# Min: 5 Max: 2950 Ignored: 0
# ----------------------------------------------
# [    5,  152) 5271  90.09%  90.09% ##########
# [  152,  299)  208   3.55%  93.64%
# [  299,  446)   29   0.50%  94.14%
# [  446,  594)    8   0.14%  94.27%
# [  594,  741)   24   0.41%  94.68%
# [  741,  888)   10   0.17%  94.86%
# [  888, 1036)    0   0.00%  94.86%
# [ 1036, 1183)    0   0.00%  94.86%
# [ 1183, 1330)    2   0.03%  94.89%
# [ 1330, 1478)    0   0.00%  94.89%
# [ 1478, 1625)    0   0.00%  94.89%
# [ 1625, 1772)    0   0.00%  94.89%
# [ 1772, 1919)    0   0.00%  94.89%
# [ 1919, 2067)    6   0.10%  94.99%
# [ 2067, 2214)   21   0.36%  95.35%
# [ 2214, 2361)   10   0.17%  95.52%
# [ 2361, 2509)   14   0.24%  95.76%
# [ 2509, 2656)   41   0.70%  96.46%
# [ 2656, 2803)  135   2.31%  98.77%
# [ 2803, 2950]   72   1.23% 100.00%
#
# Attribute in nodes:
# 	586 : 90Percentile [NUMERICAL]
# 	416 : Uniformity [NUMERICAL]
# 	411 : Maximum [NUMERICAL]
# 	389 : Skewness [NUMERICAL]
# 	350 : Minimum [NUMERICAL]
# 	350 : Entropy [NUMERICAL]
# 	321 : Energy [NUMERICAL]
# 	317 : Range [NUMERICAL]
# 	314 : TotalEnergy [NUMERICAL]
# 	287 : Mean [NUMERICAL]
# 	282 : RootMeanSquared [NUMERICAL]
# 	269 : Kurtosis [NUMERICAL]
# 	255 : 10Percentile [NUMERICAL]
# 	251 : Median [NUMERICAL]
# 	199 : RobustMeanAbsoluteDeviation [NUMERICAL]
# 	195 : MeanAbsoluteDeviation [NUMERICAL]
# 	181 : InterquartileRange [NUMERICAL]
# 	178 : Variance [NUMERICAL]
#
# Attribute in nodes with depth <= 0:
# 	85 : 90Percentile [NUMERICAL]
# 	72 : Maximum [NUMERICAL]
# 	54 : TotalEnergy [NUMERICAL]
# 	35 : Energy [NUMERICAL]
# 	27 : RootMeanSquared [NUMERICAL]
# 	14 : Mean [NUMERICAL]
# 	8 : Median [NUMERICAL]
# 	5 : 10Percentile [NUMERICAL]
#
# Attribute in nodes with depth <= 1:
# 	252 : 90Percentile [NUMERICAL]
# 	166 : Maximum [NUMERICAL]
# 	96 : TotalEnergy [NUMERICAL]
# 	91 : Energy [NUMERICAL]
# 	68 : RootMeanSquared [NUMERICAL]
# 	55 : Mean [NUMERICAL]
# 	40 : Uniformity [NUMERICAL]
# 	40 : Entropy [NUMERICAL]
# 	21 : Median [NUMERICAL]
# 	11 : InterquartileRange [NUMERICAL]
# 	11 : 10Percentile [NUMERICAL]
# 	8 : RobustMeanAbsoluteDeviation [NUMERICAL]
# 	8 : Range [NUMERICAL]
# 	6 : MeanAbsoluteDeviation [NUMERICAL]
# 	5 : Minimum [NUMERICAL]
# 	4 : Kurtosis [NUMERICAL]
# 	3 : Variance [NUMERICAL]
#
# Attribute in nodes with depth <= 2:
# 	355 : 90Percentile [NUMERICAL]
# 	229 : Maximum [NUMERICAL]
# 	157 : TotalEnergy [NUMERICAL]
# 	148 : Energy [NUMERICAL]
# 	129 : RootMeanSquared [NUMERICAL]
# 	121 : Uniformity [NUMERICAL]
# 	119 : Mean [NUMERICAL]
# 	104 : Entropy [NUMERICAL]
# 	68 : Median [NUMERICAL]
# 	65 : Minimum [NUMERICAL]
# 	44 : RobustMeanAbsoluteDeviation [NUMERICAL]
# 	44 : 10Percentile [NUMERICAL]
# 	36 : InterquartileRange [NUMERICAL]
# 	31 : Kurtosis [NUMERICAL]
# 	30 : Skewness [NUMERICAL]
# 	25 : Range [NUMERICAL]
# 	22 : MeanAbsoluteDeviation [NUMERICAL]
# 	18 : Variance [NUMERICAL]
#
# Attribute in nodes with depth <= 3:
# 	421 : 90Percentile [NUMERICAL]
# 	261 : Maximum [NUMERICAL]
# 	204 : Uniformity [NUMERICAL]
# 	194 : TotalEnergy [NUMERICAL]
# 	190 : Energy [NUMERICAL]
# 	172 : RootMeanSquared [NUMERICAL]
# 	166 : Minimum [NUMERICAL]
# 	162 : Entropy [NUMERICAL]
# 	161 : Mean [NUMERICAL]
# 	133 : Skewness [NUMERICAL]
# 	108 : Median [NUMERICAL]
# 	91 : 10Percentile [NUMERICAL]
# 	89 : Kurtosis [NUMERICAL]
# 	81 : Range [NUMERICAL]
# 	70 : RobustMeanAbsoluteDeviation [NUMERICAL]
# 	70 : InterquartileRange [NUMERICAL]
# 	50 : Variance [NUMERICAL]
# 	46 : MeanAbsoluteDeviation [NUMERICAL]
#
# Attribute in nodes with depth <= 5:
# 	505 : 90Percentile [NUMERICAL]
# 	346 : Maximum [NUMERICAL]
# 	333 : Uniformity [NUMERICAL]
# 	293 : Skewness [NUMERICAL]
# 	293 : Minimum [NUMERICAL]
# 	270 : Entropy [NUMERICAL]
# 	258 : Energy [NUMERICAL]
# 	252 : TotalEnergy [NUMERICAL]
# 	241 : RootMeanSquared [NUMERICAL]
# 	232 : Mean [NUMERICAL]
# 	210 : Range [NUMERICAL]
# 	193 : Kurtosis [NUMERICAL]
# 	186 : Median [NUMERICAL]
# 	176 : 10Percentile [NUMERICAL]
# 	130 : RobustMeanAbsoluteDeviation [NUMERICAL]
# 	126 : InterquartileRange [NUMERICAL]
# 	116 : MeanAbsoluteDeviation [NUMERICAL]
# 	113 : Variance [NUMERICAL]
#
# Condition type in nodes:
# 	5551 : HigherCondition
# Condition type in nodes with depth <= 0:
# 	300 : HigherCondition
# Condition type in nodes with depth <= 1:
# 	885 : HigherCondition
# Condition type in nodes with depth <= 2:
# 	1745 : HigherCondition
# Condition type in nodes with depth <= 3:
# 	2669 : HigherCondition
# Condition type in nodes with depth <= 5:
# 	4273 : HigherCondition
# Node format: NOT_SET
#
# Training OOB:
# 	trees: 1, Out-of-bag evaluation: accuracy:0.938878 logloss:2.20307
# 	trees: 11, Out-of-bag evaluation: accuracy:0.949628 logloss:0.494099
# 	trees: 21, Out-of-bag evaluation: accuracy:0.946982 logloss:0.373684
# 	trees: 31, Out-of-bag evaluation: accuracy:0.943584 logloss:0.279915
# 	trees: 42, Out-of-bag evaluation: accuracy:0.951076 logloss:0.27686
# 	trees: 52, Out-of-bag evaluation: accuracy:0.948311 logloss:0.27439
# 	trees: 62, Out-of-bag evaluation: accuracy:0.950755 logloss:0.190444
# 	trees: 72, Out-of-bag evaluation: accuracy:0.955642 logloss:0.189741
# 	trees: 82, Out-of-bag evaluation: accuracy:0.956124 logloss:0.18289
# 	trees: 92, Out-of-bag evaluation: accuracy:0.953359 logloss:0.183417
# 	trees: 102, Out-of-bag evaluation: accuracy:0.953519 logloss:0.182693
# 	trees: 112, Out-of-bag evaluation: accuracy:0.953359 logloss:0.182766
# 	trees: 122, Out-of-bag evaluation: accuracy:0.953519 logloss:0.183557
# 	trees: 132, Out-of-bag evaluation: accuracy:0.953519 logloss:0.184016
# 	trees: 142, Out-of-bag evaluation: accuracy:0.956284 logloss:0.177532
# 	trees: 152, Out-of-bag evaluation: accuracy:0.95368 logloss:0.178893
# 	trees: 162, Out-of-bag evaluation: accuracy:0.953519 logloss:0.179297
# 	trees: 172, Out-of-bag evaluation: accuracy:0.951076 logloss:0.180963
# 	trees: 182, Out-of-bag evaluation: accuracy:0.951076 logloss:0.180413
# 	trees: 192, Out-of-bag evaluation: accuracy:0.95368 logloss:0.17974
# 	trees: 202, Out-of-bag evaluation: accuracy:0.95368 logloss:0.180545
# 	trees: 212, Out-of-bag evaluation: accuracy:0.95368 logloss:0.181348
# 	trees: 222, Out-of-bag evaluation: accuracy:0.95384 logloss:0.180672
# 	trees: 232, Out-of-bag evaluation: accuracy:0.95384 logloss:0.181035
# 	trees: 242, Out-of-bag evaluation: accuracy:0.95384 logloss:0.18145
# 	trees: 252, Out-of-bag evaluation: accuracy:0.95368 logloss:0.181471
# 	trees: 262, Out-of-bag evaluation: accuracy:0.95384 logloss:0.180582
# 	trees: 272, Out-of-bag evaluation: accuracy:0.95384 logloss:0.180095
# 	trees: 282, Out-of-bag evaluation: accuracy:0.956445 logloss:0.179786
# 	trees: 292, Out-of-bag evaluation: accuracy:0.956284 logloss:0.179867
# 	trees: 300, Out-of-bag evaluation: accuracy:0.958888 logloss:0.175056

# %%
# Model features
model.make_inspector().features()
# Out:
# ["10Percentile" (1; #0),
#  "90Percentile" (1; #1),
#  "Energy" (1; #2),
#  "Entropy" (1; #3),
#  "InterquartileRange" (1; #4),
#  "Kurtosis" (1; #5),
#  "Maximum" (1; #6),
#  "Mean" (1; #7),
#  "MeanAbsoluteDeviation" (1; #8),
#  "Median" (1; #9),
#  "Minimum" (1; #10),
#  "Range" (1; #11),
#  "RobustMeanAbsoluteDeviation" (1; #12),
#  "RootMeanSquared" (1; #13),
#  "Skewness" (1; #14),
#  "TotalEnergy" (1; #15),
#  "Uniformity" (1; #16),
#  "Variance" (1; #17)]

# %%
# Feature importance
model.make_inspector().variable_importances()
# Out:
# {'INV_MEAN_MIN_DEPTH': [("90Percentile" (1; #1), 0.29095428813444635),
#   ("Maximum" (1; #6), 0.23239471222242425),
#   ("TotalEnergy" (1; #15), 0.2065627568738805),
#   ("Energy" (1; #2), 0.1974459042436033),
#   ("RootMeanSquared" (1; #13), 0.1876942745985183),
#   ("Uniformity" (1; #16), 0.18656734298801364),
#   ("Entropy" (1; #3), 0.18125939018512882),
#   ("Mean" (1; #7), 0.18096908949292428),
#   ("Skewness" (1; #14), 0.1808342732628414),
#   ("Minimum" (1; #10), 0.17715959803536085),
#   ("Median" (1; #9), 0.16994228116524754),
#   ("10Percentile" (1; #0), 0.16917301256875533),
#   ("Range" (1; #11), 0.16834928740651622),
#   ("Kurtosis" (1; #5), 0.1661182289565541),
#   ("RobustMeanAbsoluteDeviation" (1; #12), 0.16501388084486981),
#   ("InterquartileRange" (1; #4), 0.16328143947103493),
#   ("Variance" (1; #17), 0.1622905040588006),
#   ("MeanAbsoluteDeviation" (1; #8), 0.16171412329614915)],
#  'NUM_AS_ROOT': [("90Percentile" (1; #1), 85.0),
#   ("Maximum" (1; #6), 72.0),
#   ("TotalEnergy" (1; #15), 54.0),
#   ("Energy" (1; #2), 35.0),
#   ("RootMeanSquared" (1; #13), 27.0),
#   ("Mean" (1; #7), 14.0),
#   ("Median" (1; #9), 8.0),
#   ("10Percentile" (1; #0), 5.0)],
#  'SUM_SCORE': [("90Percentile" (1; #1), 195222.93134166862),
#   ("Maximum" (1; #6), 150610.58363561222),
#   ("TotalEnergy" (1; #15), 96811.47870086617),
#   ("Energy" (1; #2), 66569.19114707064),
#   ("RootMeanSquared" (1; #13), 50050.706154334264),
#   ("Mean" (1; #7), 28438.07335392679),
#   ("Median" (1; #9), 15150.263558601468),
#   ("Uniformity" (1; #16), 14742.686463411568),
#   ("Entropy" (1; #3), 13879.038027472441),
#   ("10Percentile" (1; #0), 9179.805111900212),
#   ("Minimum" (1; #10), 7663.347189839207),
#   ("Skewness" (1; #14), 7471.000177567011),
#   ("Range" (1; #11), 4760.482069425528),
#   ("RobustMeanAbsoluteDeviation" (1; #12), 4745.95836416981),
#   ("InterquartileRange" (1; #4), 3936.2435461723976),
#   ("Kurtosis" (1; #5), 3826.100697051226),
#   ("MeanAbsoluteDeviation" (1; #8), 2951.1840104839766),
#   ("Variance" (1; #17), 2141.5655475873236)],
#  'NUM_NODES': [("90Percentile" (1; #1), 586.0),
#   ("Uniformity" (1; #16), 416.0),
#   ("Maximum" (1; #6), 411.0),
#   ("Skewness" (1; #14), 389.0),
#   ("Entropy" (1; #3), 350.0),
#   ("Minimum" (1; #10), 350.0),
#   ("Energy" (1; #2), 321.0),
#   ("Range" (1; #11), 317.0),
#   ("TotalEnergy" (1; #15), 314.0),
#   ("Mean" (1; #7), 287.0),
#   ("RootMeanSquared" (1; #13), 282.0),
#   ("Kurtosis" (1; #5), 269.0),
#   ("10Percentile" (1; #0), 255.0),
#   ("Median" (1; #9), 251.0),
#   ("RobustMeanAbsoluteDeviation" (1; #12), 199.0),
#   ("MeanAbsoluteDeviation" (1; #8), 195.0),
#   ("InterquartileRange" (1; #4), 181.0),
#   ("Variance" (1; #17), 178.0)]}

# %%
# Model self evaluation
model.make_inspector().evaluation()
# Out:
# Evaluation(num_examples=3308, accuracy=0.9588882659858348, loss=0.17505552069719127, rmse=None, ndcg=None, aucs=None, auuc=None, qini=None)

# %%
logs = model.make_inspector().training_logs()

plt.figure(figsize=(12, 4))
plt.subplot(1, 2, 1)
plt.plot([log.num_trees for log in logs], [log.evaluation.accuracy for log in logs])
plt.xlabel("Number of trees")
plt.ylabel("Accuracy (out-of-bag)")
plt.subplot(1, 2, 2)
plt.plot([log.num_trees for log in logs], [log.evaluation.loss for log in logs])
plt.xlabel("Number of trees")
plt.ylabel("Logloss (out-of-bag)")
plt.show()

# %% [markdown]
# Calculate the score of our hold-out validation dataset

# %%
predictions = model.predict(val_ds)
y_true      = validation_data["label"]

from sklearn.metrics import roc_auc_score
ROC_AUC = roc_auc_score(y_true, predictions)
print("The ROC AUC score is %.5f" % ROC_AUC )
# Out:
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 65ms/step
# The ROC AUC score is 0.99883

# %%
# Compute binary classification metrics with sklearn
import numpy as np
from sklearn.metrics import (
    accuracy_score,
    precision_score,
    recall_score,
    f1_score,
    roc_auc_score,
    average_precision_score,
    confusion_matrix,
    classification_report,
    matthews_corrcoef,
    log_loss,
    brier_score_loss,
)

# Get predictions (probabilities or class labels)
preds = model.predict(test_ds)
# If model outputs probabilities, convert to labels by threshold 0.5
if preds.ndim == 2:
    # For TFDF classification, preds may be class probabilities with shape (N, 2)
    if preds.shape[1] == 2:
        pos_probs = preds[:, 1]
    else:
        # If single-probability column (positive class)
        pos_probs = preds[:, -1]
    y_pred = (pos_probs >= 0.5).astype(int)
else:
    # Already class labels
    y_pred = preds.astype(int)
    pos_probs = None

# Ground truth labels (must be 0/1 integers)
y_true = test_data["label"].astype(int).to_numpy()

# Core metrics
metrics = {}
metrics["accuracy"] = accuracy_score(y_true, y_pred)
metrics["precision"] = precision_score(y_true, y_pred, zero_division=0)
metrics["recall"] = recall_score(y_true, y_pred, zero_division=0)
metrics["f1"] = f1_score(y_true, y_pred, zero_division=0)
metrics["mcc"] = matthews_corrcoef(y_true, y_pred)

# Probabilistic metrics (only if we have probabilities)
if pos_probs is not None:
    metrics["roc_auc"] = roc_auc_score(y_true, pos_probs)
    metrics["pr_auc"] = average_precision_score(y_true, pos_probs)
    metrics["log_loss"] = log_loss(y_true, pos_probs, labels=[0,1])
    metrics["brier_score"] = brier_score_loss(y_true, pos_probs)

# Confusion matrix and detailed report
cm = confusion_matrix(y_true, y_pred, labels=[0,1])
report = classification_report(y_true, y_pred, digits=4)

print("Sklearn binary metrics:")
for k, v in metrics.items():
    print(f"{k}: {v:.4f}")
print("\nConfusion matrix:\n", cm)
print("\nClassification report:\n", report)
# Out:
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 74ms/step
# Sklearn binary metrics:
# accuracy: 0.9915
# precision: 0.9180
# recall: 0.9492
# f1: 0.9333
# mcc: 0.9290
# roc_auc: 0.9893
# pr_auc: 0.9731
# log_loss: 0.0402
# brier_score: 0.0075
#
# Confusion matrix:
#  [[882   5]
#  [  3  56]]
#
# Classification report:
#                precision    recall  f1-score   support
#
#            0     0.9966    0.9944    0.9955       887
#            1     0.9180    0.9492    0.9333        59
#
#     accuracy                         0.9915       946
#    macro avg     0.9573    0.9718    0.9644       946
# weighted avg     0.9917    0.9915    0.9916       946
