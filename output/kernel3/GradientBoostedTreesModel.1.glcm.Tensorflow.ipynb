# %%
# Import packages and modules
import numpy  as np
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow_decision_forests as tfdf

from sklearn.model_selection import train_test_split
# Out:
# 2026-08-15 04:54:58.219522: I tensorflow/core/util/port.cc:113] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2026-08-15 04:54:58.652404: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2026-08-15 04:55:03.431855: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
# Check the version of TensorFlow Decision Forests
print("Found TensorFlow Decision Forests v" + tfdf.__version__)
# Out:
# Found TensorFlow Decision Forests v1.9.1

# %%
datasetPath = 'dataset/firstorder/kernel5/dataset.csv'

# %%
# Parameters
datasetPath = "dataset/glcm/kernel3/1.dataset.csv"

# %%
# train/validation/test = 70/10/20
dataset = pd.read_csv(datasetPath)

train_data, temp_data = train_test_split(dataset, test_size=0.3, random_state=42)
validation_data, test_data = train_test_split(temp_data, test_size=2/3, random_state=42)

# %%
from sklearn.utils.class_weight import compute_class_weight

# tinh class weight tren tap train
classes = np.array([0, 1])
weights = compute_class_weight(class_weight="balanced", classes=classes, y=train_data["label"])
class_weight = {0: weights[0], 1: weights[1]}

# gan sample_weight cho tung dong
train_data["sample_weight"] = train_data["label"].map(class_weight)
validation_data["sample_weight"] = validation_data["label"].map(class_weight)
test_data["sample_weight"] = test_data["label"].map(class_weight)

# Convert the dataset into a TensorFlow dataset.
train_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    train_data, label="label", weight="sample_weight"
)         
val_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    validation_data, label="label", weight="sample_weight"
)
test_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    test_data, label="label", weight="sample_weight"
)
# Out:
# 2026-08-15 04:55:17.115192: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:984] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2026-08-15 04:55:17.116337: W tensorflow/core/common_runtime/gpu/gpu_device.cc:2251] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...

# %%
import keras

# %%
# %%time

# Train a Gradient Boosted Trees model.
model = tfdf.keras.GradientBoostedTreesModel()

# Add evaluation metrics
model.compile(
    metrics=["accuracy"]
)
model.fit(x=train_ds)

# # Train a Gradient Boosted Trees model.
# model = tfdf.keras.GradientBoostedTreesModel(num_trees=1500)
# model.fit(train_ds)
# Out:
# Use /tmp/tmp2m_sh7ju as temporary training directory
# Reading training dataset...
# [WARNING 26-08-15 04:55:17.2650 UTC gradient_boosted_trees.cc:1840] "goss_alpha" set but "sampling_method" not equal to "GOSS".
# [WARNING 26-08-15 04:55:17.2652 UTC gradient_boosted_trees.cc:1851] "goss_beta" set but "sampling_method" not equal to "GOSS".
# [WARNING 26-08-15 04:55:17.2652 UTC gradient_boosted_trees.cc:1865] "selective_gradient_boosting_ratio" set but "sampling_method" not equal to "SELGB".
# Training dataset read in 0:00:02.632724. Found 3308 examples.
# Training model...
# Model trained in 0:00:00.761129
# Compiling model...
# [INFO 26-08-15 04:55:20.6867 UTC kernel.cc:1233] Loading model from path /tmp/tmp2m_sh7ju/model/ with prefix ae4a63944c664783
# [INFO 26-08-15 04:55:20.6904 UTC quick_scorer_extended.cc:911] The binary was compiled without AVX2 support, but your CPU supports it. Enable it for faster model inference.
# [INFO 26-08-15 04:55:20.6907 UTC abstract_model.cc:1362] Engine "GradientBoostedTreesQuickScorerExtended" built
# [INFO 26-08-15 04:55:20.6907 UTC kernel.cc:1061] Use fast generic engine
# Model compiled.
# CPU times: user 7.56 s, sys: 952 ms, total: 8.51 s
# Wall time: 6.66 s

# %%
# Evaluate the model
evaluate = model.evaluate(val_ds, return_dict=True)
print()

for name, value in evaluate.items():
    print(f"{name}: {value:.4f}")
# Out:
# WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 1/1 [==============================] - ETA: 0s - loss: 0.0000e+00 - accuracy: 0.9810
# 1/1 [==============================] - 3s 3s/step - loss: 0.0000e+00 - accuracy: 0.9810
# loss: 0.0000
# accuracy: 0.9810

# %%
# Model Summary
model.summary()
# Out:
# Model: "gradient_boosted_trees_model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
# =================================================================
# Total params: 1 (1.00 Byte)
# Trainable params: 0 (0.00 Byte)
# Non-trainable params: 1 (1.00 Byte)
# _________________________________________________________________
# Type: "GRADIENT_BOOSTED_TREES"
# Task: CLASSIFICATION
# Label: "__LABEL"
#
# Input Features (24):
# 	Autocorrelation
# 	ClusterProminence
# 	ClusterShade
# 	ClusterTendency
# 	Contrast
# 	Correlation
# 	DifferenceAverage
# 	DifferenceEntropy
# 	DifferenceVariance
# 	Id
# 	Idm
# 	Idmn
# 	Idn
# 	Imc1
# 	Imc2
# 	InverseVariance
# 	JointAverage
# 	JointEnergy
# 	JointEntropy
# 	MCC
# 	MaximumProbability
# 	SumAverage
# 	SumEntropy
# 	SumSquares
#
# Trained with weights
#
# Variable Importance: INV_MEAN_MIN_DEPTH:
#     1.    "Autocorrelation"  0.490534 ################
#     2.       "JointAverage"  0.228445 ##
#     3.         "SumAverage"  0.222234 ##
#     4.        "Correlation"  0.221646 ##
#     5.         "SumEntropy"  0.209036 #
#     6.               "Imc2"  0.199538 #
#     7.       "ClusterShade"  0.195095
#     8.               "Imc1"  0.188690
#     9. "MaximumProbability"  0.188354
#    10.       "JointEntropy"  0.184007
#    11. "DifferenceVariance"  0.183268
#    12.    "InverseVariance"  0.183111
#    13.  "ClusterProminence"  0.181774
#    14.                 "Id"  0.181698
#    15.                "Idm"  0.180892
#    16.                "MCC"  0.180072
#    17.           "Contrast"  0.180056
#    18.  "DifferenceEntropy"  0.179494
#    19.         "SumSquares"  0.179342
#    20.        "JointEnergy"  0.179324
#    21.                "Idn"  0.178974
#    22.  "DifferenceAverage"  0.178591
#    23.               "Idmn"  0.178418
#    24.    "ClusterTendency"  0.178405
#
# Variable Importance: NUM_AS_ROOT:
#     1. "Autocorrelation" 49.000000 ################
#     2.    "JointAverage" 13.000000 ###
#     3.      "SumAverage"  9.000000 ##
#     4.            "Imc2"  2.000000
#
# Variable Importance: NUM_NODES:
#     1.    "Autocorrelation" 306.000000 ################
#     2.        "Correlation" 178.000000 #########
#     3.       "ClusterShade" 128.000000 ######
#     4.         "SumEntropy" 103.000000 #####
#     5.         "SumAverage" 99.000000 ####
#     6.       "JointAverage" 92.000000 ####
#     7.               "Imc2" 86.000000 ####
#     8.               "Imc1" 69.000000 ###
#     9. "MaximumProbability" 56.000000 ##
#    10. "DifferenceVariance" 51.000000 ##
#    11.    "InverseVariance" 44.000000 #
#    12.                "MCC" 39.000000 #
#    13.       "JointEntropy" 35.000000 #
#    14.  "ClusterProminence" 33.000000 #
#    15.        "JointEnergy" 30.000000 #
#    16.                 "Id" 29.000000 #
#    17.  "DifferenceEntropy" 21.000000
#    18.                "Idm" 18.000000
#    19.         "SumSquares" 17.000000
#    20.                "Idn" 16.000000
#    21.           "Contrast" 13.000000
#    22.  "DifferenceAverage" 13.000000
#    23.    "ClusterTendency" 11.000000
#    24.               "Idmn"  9.000000
#
# Variable Importance: SUM_SCORE:
#     1.    "Autocorrelation" 3431.807264 ################
#     2.               "Imc1" 161.930123
#     3.        "Correlation" 96.644462
#     4.               "Imc2" 94.335076
#     5.       "ClusterShade" 77.019731
#     6.         "SumEntropy" 58.283253
#     7. "DifferenceVariance" 15.351526
#     8.                 "Id" 13.642507
#     9.         "SumAverage"  9.548791
#    10.    "InverseVariance"  9.073848
#    11.                "Idn"  6.848773
#    12.       "JointAverage"  6.292397
#    13.       "JointEntropy"  4.614640
#    14. "MaximumProbability"  3.949355
#    15.                "Idm"  3.339516
#    16.  "DifferenceAverage"  2.635235
#    17.                "MCC"  1.760352
#    18.        "JointEnergy"  1.758842
#    19.    "ClusterTendency"  1.386105
#    20.         "SumSquares"  1.102543
#    21.               "Idmn"  0.764097
#    22.  "DifferenceEntropy"  0.714882
#    23.  "ClusterProminence"  0.454436
#    24.           "Contrast"  0.400964
#
#
#
# Loss: BINOMIAL_LOG_LIKELIHOOD
# Validation loss value: 0.101234
# Number of trees per iteration: 1
# Node format: NOT_SET
# Number of trees: 73
# Total number of nodes: 3065
#
# Number of nodes by tree:
# Count: 73 Average: 41.9863 StdDev: 7.07783
# Min: 27 Max: 53 Ignored: 0
# ----------------------------------------------
# [ 27, 28)  3   4.11%   4.11% ###
# [ 28, 29)  0   0.00%   4.11%
# [ 29, 31)  1   1.37%   5.48% #
# [ 31, 32)  3   4.11%   9.59% ###
# [ 32, 33)  0   0.00%   9.59%
# [ 33, 35)  2   2.74%  12.33% ##
# [ 35, 36)  8  10.96%  23.29% #######
# [ 36, 37)  0   0.00%  23.29%
# [ 37, 39)  6   8.22%  31.51% #####
# [ 39, 40)  7   9.59%  41.10% ######
# [ 40, 41)  0   0.00%  41.10%
# [ 41, 43)  8  10.96%  52.05% #######
# [ 43, 44)  3   4.11%  56.16% ###
# [ 44, 45)  0   0.00%  56.16%
# [ 45, 47)  2   2.74%  58.90% ##
# [ 47, 48) 11  15.07%  73.97% ##########
# [ 48, 49)  0   0.00%  73.97%
# [ 49, 51) 10  13.70%  87.67% #########
# [ 51, 52)  5   6.85%  94.52% #####
# [ 52, 53]  4   5.48% 100.00% ####
#
# Depth by leafs:
# Count: 1569 Average: 4.64308 StdDev: 0.668001
# Min: 2 Max: 5 Ignored: 0
# ----------------------------------------------
# [ 2, 3)   37   2.36%   2.36%
# [ 3, 4)   59   3.76%   6.12% #
# [ 4, 5)  331  21.10%  27.21% ###
# [ 5, 5] 1142  72.79% 100.00% ##########
#
# Number of training obs by leaf:
# Count: 1569 Average: 139.161 StdDev: 492.438
# Min: 5 Max: 2706 Ignored: 0
# ----------------------------------------------
# [    5,  140) 1409  89.80%  89.80% ##########
# [  140,  275)   70   4.46%  94.26%
# [  275,  410)   10   0.64%  94.90%
# [  410,  545)    6   0.38%  95.28%
# [  545,  680)    0   0.00%  95.28%
# [  680,  815)    1   0.06%  95.35%
# [  815,  950)    0   0.00%  95.35%
# [  950, 1085)    0   0.00%  95.35%
# [ 1085, 1220)    0   0.00%  95.35%
# [ 1220, 1356)    0   0.00%  95.35%
# [ 1356, 1491)    0   0.00%  95.35%
# [ 1491, 1626)    0   0.00%  95.35%
# [ 1626, 1761)    1   0.06%  95.41%
# [ 1761, 1896)    3   0.19%  95.60%
# [ 1896, 2031)    1   0.06%  95.67%
# [ 2031, 2166)    9   0.57%  96.24%
# [ 2166, 2301)    9   0.57%  96.81%
# [ 2301, 2436)   36   2.29%  99.11%
# [ 2436, 2571)    3   0.19%  99.30%
# [ 2571, 2706]   11   0.70% 100.00%
#
# Attribute in nodes:
# 	306 : Autocorrelation [NUMERICAL]
# 	178 : Correlation [NUMERICAL]
# 	128 : ClusterShade [NUMERICAL]
# 	103 : SumEntropy [NUMERICAL]
# 	99 : SumAverage [NUMERICAL]
# 	92 : JointAverage [NUMERICAL]
# 	86 : Imc2 [NUMERICAL]
# 	69 : Imc1 [NUMERICAL]
# 	56 : MaximumProbability [NUMERICAL]
# 	51 : DifferenceVariance [NUMERICAL]
# 	44 : InverseVariance [NUMERICAL]
# 	39 : MCC [NUMERICAL]
# 	35 : JointEntropy [NUMERICAL]
# 	33 : ClusterProminence [NUMERICAL]
# 	30 : JointEnergy [NUMERICAL]
# 	29 : Id [NUMERICAL]
# 	21 : DifferenceEntropy [NUMERICAL]
# 	18 : Idm [NUMERICAL]
# 	17 : SumSquares [NUMERICAL]
# 	16 : Idn [NUMERICAL]
# 	13 : DifferenceAverage [NUMERICAL]
# 	13 : Contrast [NUMERICAL]
# 	11 : ClusterTendency [NUMERICAL]
# 	9 : Idmn [NUMERICAL]
#
# Attribute in nodes with depth <= 0:
# 	49 : Autocorrelation [NUMERICAL]
# 	13 : JointAverage [NUMERICAL]
# 	9 : SumAverage [NUMERICAL]
# 	2 : Imc2 [NUMERICAL]
#
# Attribute in nodes with depth <= 1:
# 	104 : Autocorrelation [NUMERICAL]
# 	28 : JointAverage [NUMERICAL]
# 	26 : SumAverage [NUMERICAL]
# 	19 : SumEntropy [NUMERICAL]
# 	17 : Correlation [NUMERICAL]
# 	6 : MaximumProbability [NUMERICAL]
# 	5 : ClusterShade [NUMERICAL]
# 	3 : JointEntropy [NUMERICAL]
# 	3 : Imc1 [NUMERICAL]
# 	2 : Imc2 [NUMERICAL]
# 	2 : Idm [NUMERICAL]
# 	2 : Contrast [NUMERICAL]
# 	2 : ClusterProminence [NUMERICAL]
#
# Attribute in nodes with depth <= 2:
# 	153 : Autocorrelation [NUMERICAL]
# 	57 : Correlation [NUMERICAL]
# 	50 : SumEntropy [NUMERICAL]
# 	43 : Imc2 [NUMERICAL]
# 	42 : SumAverage [NUMERICAL]
# 	41 : JointAverage [NUMERICAL]
# 	19 : Imc1 [NUMERICAL]
# 	15 : ClusterShade [NUMERICAL]
# 	12 : MaximumProbability [NUMERICAL]
# 	10 : Id [NUMERICAL]
# 	9 : DifferenceVariance [NUMERICAL]
# 	6 : InverseVariance [NUMERICAL]
# 	6 : ClusterProminence [NUMERICAL]
# 	4 : JointEntropy [NUMERICAL]
# 	3 : Contrast [NUMERICAL]
# 	2 : Idm [NUMERICAL]
# 	1 : SumSquares [NUMERICAL]
# 	1 : DifferenceEntropy [NUMERICAL]
#
# Attribute in nodes with depth <= 3:
# 	237 : Autocorrelation [NUMERICAL]
# 	112 : Correlation [NUMERICAL]
# 	82 : ClusterShade [NUMERICAL]
# 	73 : SumEntropy [NUMERICAL]
# 	63 : SumAverage [NUMERICAL]
# 	58 : JointAverage [NUMERICAL]
# 	56 : Imc2 [NUMERICAL]
# 	39 : Imc1 [NUMERICAL]
# 	31 : DifferenceVariance [NUMERICAL]
# 	30 : MaximumProbability [NUMERICAL]
# 	24 : InverseVariance [NUMERICAL]
# 	18 : ClusterProminence [NUMERICAL]
# 	17 : JointEntropy [NUMERICAL]
# 	17 : Id [NUMERICAL]
# 	10 : MCC [NUMERICAL]
# 	10 : Idn [NUMERICAL]
# 	8 : SumSquares [NUMERICAL]
# 	8 : Idm [NUMERICAL]
# 	8 : Contrast [NUMERICAL]
# 	7 : DifferenceEntropy [NUMERICAL]
# 	5 : JointEnergy [NUMERICAL]
# 	5 : DifferenceAverage [NUMERICAL]
# 	4 : Idmn [NUMERICAL]
# 	3 : ClusterTendency [NUMERICAL]
#
# Attribute in nodes with depth <= 5:
# 	306 : Autocorrelation [NUMERICAL]
# 	178 : Correlation [NUMERICAL]
# 	128 : ClusterShade [NUMERICAL]
# 	103 : SumEntropy [NUMERICAL]
# 	99 : SumAverage [NUMERICAL]
# 	92 : JointAverage [NUMERICAL]
# 	86 : Imc2 [NUMERICAL]
# 	69 : Imc1 [NUMERICAL]
# 	56 : MaximumProbability [NUMERICAL]
# 	51 : DifferenceVariance [NUMERICAL]
# 	44 : InverseVariance [NUMERICAL]
# 	39 : MCC [NUMERICAL]
# 	35 : JointEntropy [NUMERICAL]
# 	33 : ClusterProminence [NUMERICAL]
# 	30 : JointEnergy [NUMERICAL]
# 	29 : Id [NUMERICAL]
# 	21 : DifferenceEntropy [NUMERICAL]
# 	18 : Idm [NUMERICAL]
# 	17 : SumSquares [NUMERICAL]
# 	16 : Idn [NUMERICAL]
# 	13 : DifferenceAverage [NUMERICAL]
# 	13 : Contrast [NUMERICAL]
# 	11 : ClusterTendency [NUMERICAL]
# 	9 : Idmn [NUMERICAL]
#
# Condition type in nodes:
# 	1496 : HigherCondition
# Condition type in nodes with depth <= 0:
# 	73 : HigherCondition
# Condition type in nodes with depth <= 1:
# 	219 : HigherCondition
# Condition type in nodes with depth <= 2:
# 	474 : HigherCondition
# Condition type in nodes with depth <= 3:
# 	925 : HigherCondition
# Condition type in nodes with depth <= 5:
# 	1496 : HigherCondition
#
# Training logs:
# Number of iteration to final model: 73
# 	Iter:1 train-loss:1.200241 valid-loss:1.200146  train-accuracy:0.993954 valid-accuracy:0.991639
# 	Iter:2 train-loss:1.047998 valid-loss:1.047115  train-accuracy:0.994488 valid-accuracy:0.993312
# 	Iter:3 train-loss:0.920840 valid-loss:0.919141  train-accuracy:0.994488 valid-accuracy:0.993312
# 	Iter:4 train-loss:0.812904 valid-loss:0.817834  train-accuracy:0.994488 valid-accuracy:0.994984
# 	Iter:5 train-loss:0.721123 valid-loss:0.725770  train-accuracy:0.994488 valid-accuracy:0.993312
# 	Iter:6 train-loss:0.641690 valid-loss:0.652752  train-accuracy:0.995377 valid-accuracy:0.993312
# 	Iter:16 train-loss:0.227387 valid-loss:0.259883  train-accuracy:0.995555 valid-accuracy:0.994984
# 	Iter:26 train-loss:0.088695 valid-loss:0.184884  train-accuracy:0.997866 valid-accuracy:0.970250
# 	Iter:36 train-loss:0.037346 valid-loss:0.138981  train-accuracy:0.998755 valid-accuracy:0.970250
# 	Iter:46 train-loss:0.018827 valid-loss:0.120623  train-accuracy:0.999467 valid-accuracy:0.970250
# 	Iter:56 train-loss:0.010274 valid-loss:0.110799  train-accuracy:1.000000 valid-accuracy:0.970250
# 	Iter:66 train-loss:0.006180 valid-loss:0.108935  train-accuracy:1.000000 valid-accuracy:0.970250
# 	Iter:76 train-loss:0.003853 valid-loss:0.103316  train-accuracy:1.000000 valid-accuracy:0.970250
# 	Iter:86 train-loss:0.002324 valid-loss:0.106419  train-accuracy:1.000000 valid-accuracy:0.970250
# 	Iter:96 train-loss:0.001469 valid-loss:0.116188  train-accuracy:1.000000 valid-accuracy:0.970250

# %%
# Model features
model.make_inspector().features()
# Out:
# ["Autocorrelation" (1; #0),
#  "ClusterProminence" (1; #1),
#  "ClusterShade" (1; #2),
#  "ClusterTendency" (1; #3),
#  "Contrast" (1; #4),
#  "Correlation" (1; #5),
#  "DifferenceAverage" (1; #6),
#  "DifferenceEntropy" (1; #7),
#  "DifferenceVariance" (1; #8),
#  "Id" (1; #9),
#  "Idm" (1; #10),
#  "Idmn" (1; #11),
#  "Idn" (1; #12),
#  "Imc1" (1; #13),
#  "Imc2" (1; #14),
#  "InverseVariance" (1; #15),
#  "JointAverage" (1; #16),
#  "JointEnergy" (1; #17),
#  "JointEntropy" (1; #18),
#  "MCC" (1; #19),
#  "MaximumProbability" (1; #20),
#  "SumAverage" (1; #21),
#  "SumEntropy" (1; #22),
#  "SumSquares" (1; #23)]

# %%
# Feature importance
model.make_inspector().variable_importances()
# Out:
# {'INV_MEAN_MIN_DEPTH': [("Autocorrelation" (1; #0), 0.49053419492841227),
#   ("JointAverage" (1; #16), 0.22844479024204828),
#   ("SumAverage" (1; #21), 0.22223444402289483),
#   ("Correlation" (1; #5), 0.22164619701553276),
#   ("SumEntropy" (1; #22), 0.20903644011832007),
#   ("Imc2" (1; #14), 0.19953805215889026),
#   ("ClusterShade" (1; #2), 0.19509488873990868),
#   ("Imc1" (1; #13), 0.18869041966997052),
#   ("MaximumProbability" (1; #20), 0.18835446998198435),
#   ("JointEntropy" (1; #18), 0.1840070856793894),
#   ("DifferenceVariance" (1; #8), 0.18326783418851136),
#   ("InverseVariance" (1; #15), 0.18311053439988684),
#   ("ClusterProminence" (1; #1), 0.1817735523063967),
#   ("Id" (1; #9), 0.1816975877677849),
#   ("Idm" (1; #10), 0.1808921748245349),
#   ("MCC" (1; #19), 0.18007186059506305),
#   ("Contrast" (1; #4), 0.18005555545954488),
#   ("DifferenceEntropy" (1; #7), 0.17949413497547992),
#   ("SumSquares" (1; #23), 0.17934249091177076),
#   ("JointEnergy" (1; #17), 0.17932352894355247),
#   ("Idn" (1; #12), 0.1789740977446965),
#   ("DifferenceAverage" (1; #6), 0.17859140624452627),
#   ("Idmn" (1; #11), 0.17841814644861492),
#   ("ClusterTendency" (1; #3), 0.1784048985886184)],
#  'NUM_AS_ROOT': [("Autocorrelation" (1; #0), 49.0),
#   ("JointAverage" (1; #16), 13.0),
#   ("SumAverage" (1; #21), 9.0),
#   ("Imc2" (1; #14), 2.0)],
#  'SUM_SCORE': [("Autocorrelation" (1; #0), 3431.80726446107),
#   ("Imc1" (1; #13), 161.9301234199291),
#   ("Correlation" (1; #5), 96.64446192095961),
#   ("Imc2" (1; #14), 94.33507640884973),
#   ("ClusterShade" (1; #2), 77.01973103808658),
#   ("SumEntropy" (1; #22), 58.283253022065665),
#   ("DifferenceVariance" (1; #8), 15.351526158733272),
#   ("Id" (1; #9), 13.642506997160265),
#   ("SumAverage" (1; #21), 9.548790824319136),
#   ("InverseVariance" (1; #15), 9.073847613002824),
#   ("Idn" (1; #12), 6.848773474139091),
#   ("JointAverage" (1; #16), 6.292397420851512),
#   ("JointEntropy" (1; #18), 4.6146399615795834),
#   ("MaximumProbability" (1; #20), 3.9493554876323134),
#   ("Idm" (1; #10), 3.3395155975452333),
#   ("DifferenceAverage" (1; #6), 2.6352345512996203),
#   ("MCC" (1; #19), 1.7603516080394623),
#   ("JointEnergy" (1; #17), 1.758842479608593),
#   ("ClusterTendency" (1; #3), 1.3861048783059828),
#   ("SumSquares" (1; #23), 1.1025430634307019),
#   ("Idmn" (1; #11), 0.7640973126452485),
#   ("DifferenceEntropy" (1; #7), 0.714881617493947),
#   ("ClusterProminence" (1; #1), 0.4544363902470567),
#   ("Contrast" (1; #4), 0.40096401205227583)],
#  'NUM_NODES': [("Autocorrelation" (1; #0), 306.0),
#   ("Correlation" (1; #5), 178.0),
#   ("ClusterShade" (1; #2), 128.0),
#   ("SumEntropy" (1; #22), 103.0),
#   ("SumAverage" (1; #21), 99.0),
#   ("JointAverage" (1; #16), 92.0),
#   ("Imc2" (1; #14), 86.0),
#   ("Imc1" (1; #13), 69.0),
#   ("MaximumProbability" (1; #20), 56.0),
#   ("DifferenceVariance" (1; #8), 51.0),
#   ("InverseVariance" (1; #15), 44.0),
#   ("MCC" (1; #19), 39.0),
#   ("JointEntropy" (1; #18), 35.0),
#   ("ClusterProminence" (1; #1), 33.0),
#   ("JointEnergy" (1; #17), 30.0),
#   ("Id" (1; #9), 29.0),
#   ("DifferenceEntropy" (1; #7), 21.0),
#   ("Idm" (1; #10), 18.0),
#   ("SumSquares" (1; #23), 17.0),
#   ("Idn" (1; #12), 16.0),
#   ("Contrast" (1; #4), 13.0),
#   ("DifferenceAverage" (1; #6), 13.0),
#   ("ClusterTendency" (1; #3), 11.0),
#   ("Idmn" (1; #11), 9.0)]}

# %%
# Model self evaluation
model.make_inspector().evaluation()
# Out:
# Evaluation(num_examples=None, accuracy=0.9702499508857727, loss=0.10123446583747864, rmse=None, ndcg=None, aucs=None, auuc=None, qini=None)

# %%
logs = model.make_inspector().training_logs()

plt.figure(figsize=(12, 4))
plt.subplot(1, 2, 1)
plt.plot([log.num_trees for log in logs], [log.evaluation.accuracy for log in logs])
plt.xlabel("Number of trees")
plt.ylabel("Accuracy (out-of-bag)")
plt.subplot(1, 2, 2)
plt.plot([log.num_trees for log in logs], [log.evaluation.loss for log in logs])
plt.xlabel("Number of trees")
plt.ylabel("Logloss (out-of-bag)")
plt.show()

# %% [markdown]
# Calculate the score of our hold-out validation dataset

# %%
predictions = model.predict(val_ds)
y_true      = validation_data["label"]

from sklearn.metrics import roc_auc_score
ROC_AUC = roc_auc_score(y_true, predictions)
print("The ROC AUC score is %.5f" % ROC_AUC )
# Out:
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 67ms/step
# The ROC AUC score is 0.96168

# %%
# Compute binary classification metrics with sklearn
import numpy as np
from sklearn.metrics import (
    accuracy_score,
    precision_score,
    recall_score,
    f1_score,
    roc_auc_score,
    average_precision_score,
    confusion_matrix,
    classification_report,
    matthews_corrcoef,
    log_loss,
    brier_score_loss,
)

# Get predictions (probabilities or class labels)
preds = model.predict(test_ds)
# If model outputs probabilities, convert to labels by threshold 0.5
if preds.ndim == 2:
    # For TFDF classification, preds may be class probabilities with shape (N, 2)
    if preds.shape[1] == 2:
        pos_probs = preds[:, 1]
    else:
        # If single-probability column (positive class)
        pos_probs = preds[:, -1]
    y_pred = (pos_probs >= 0.5).astype(int)
else:
    # Already class labels
    y_pred = preds.astype(int)
    pos_probs = None

# Ground truth labels (must be 0/1 integers)
y_true = test_data["label"].astype(int).to_numpy()

# Core metrics
metrics = {}
metrics["accuracy"] = accuracy_score(y_true, y_pred)
metrics["precision"] = precision_score(y_true, y_pred, zero_division=0)
metrics["recall"] = recall_score(y_true, y_pred, zero_division=0)
metrics["f1"] = f1_score(y_true, y_pred, zero_division=0)
metrics["mcc"] = matthews_corrcoef(y_true, y_pred)

# Probabilistic metrics (only if we have probabilities)
if pos_probs is not None:
    metrics["roc_auc"] = roc_auc_score(y_true, pos_probs)
    metrics["pr_auc"] = average_precision_score(y_true, pos_probs)
    metrics["log_loss"] = log_loss(y_true, pos_probs, labels=[0,1])
    metrics["brier_score"] = brier_score_loss(y_true, pos_probs)

# Confusion matrix and detailed report
cm = confusion_matrix(y_true, y_pred, labels=[0,1])
report = classification_report(y_true, y_pred, digits=4)

print("Sklearn binary metrics:")
for k, v in metrics.items():
    print(f"{k}: {v:.4f}")
print("\nConfusion matrix:\n", cm)
print("\nClassification report:\n", report)
# Out:
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 79ms/step
# Sklearn binary metrics:
# accuracy: 0.9937
# precision: 0.9615
# recall: 0.9259
# f1: 0.9434
# mcc: 0.9402
# roc_auc: 0.9875
# pr_auc: 0.9517
# log_loss: 0.0354
# brier_score: 0.0064
#
# Confusion matrix:
#  [[890   2]
#  [  4  50]]
#
# Classification report:
#                precision    recall  f1-score   support
#
#            0     0.9955    0.9978    0.9966       892
#            1     0.9615    0.9259    0.9434        54
#
#     accuracy                         0.9937       946
#    macro avg     0.9785    0.9618    0.9700       946
# weighted avg     0.9936    0.9937    0.9936       946
