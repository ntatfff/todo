# %%
# Import packages and modules
import numpy  as np
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow_decision_forests as tfdf

from sklearn.model_selection import train_test_split
# Out:
# 2026-08-15 04:56:12.383937: I tensorflow/core/util/port.cc:113] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2026-08-15 04:56:12.794206: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2026-08-15 04:56:17.650771: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
# Check the version of TensorFlow Decision Forests
print("Found TensorFlow Decision Forests v" + tfdf.__version__)
# Out:
# Found TensorFlow Decision Forests v1.9.1

# %%
datasetPath = 'dataset/firstorder/kernel5/dataset.csv'

# %%
# Parameters
datasetPath = "dataset/glrlm/kernel3/1.dataset.csv"

# %%
# train/validation/test = 70/10/20
dataset = pd.read_csv(datasetPath)

train_data, temp_data = train_test_split(dataset, test_size=0.3, random_state=42)
validation_data, test_data = train_test_split(temp_data, test_size=2/3, random_state=42)

# %%
from sklearn.utils.class_weight import compute_class_weight

# tinh class weight tren tap train
classes = np.array([0, 1])
weights = compute_class_weight(class_weight="balanced", classes=classes, y=train_data["label"])
class_weight = {0: weights[0], 1: weights[1]}

# gan sample_weight cho tung dong
train_data["sample_weight"] = train_data["label"].map(class_weight)
validation_data["sample_weight"] = validation_data["label"].map(class_weight)
test_data["sample_weight"] = test_data["label"].map(class_weight)

# Convert the dataset into a TensorFlow dataset.
train_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    train_data, label="label", weight="sample_weight"
)         
val_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    validation_data, label="label", weight="sample_weight"
)
test_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    test_data, label="label", weight="sample_weight"
)
# Out:
# 2026-08-15 04:56:30.679910: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:984] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2026-08-15 04:56:30.681245: W tensorflow/core/common_runtime/gpu/gpu_device.cc:2251] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...

# %%
import keras

# %%
# %%time

# Train a Gradient Boosted Trees model.
model = tfdf.keras.GradientBoostedTreesModel()

# Add evaluation metrics
model.compile(
    metrics=["accuracy"]
)
model.fit(x=train_ds)

# # Train a Gradient Boosted Trees model.
# model = tfdf.keras.GradientBoostedTreesModel(num_trees=1500)
# model.fit(train_ds)
# Out:
# Use /tmp/tmp95q6skpe as temporary training directory
# Reading training dataset...
# [WARNING 26-08-15 04:56:30.8356 UTC gradient_boosted_trees.cc:1840] "goss_alpha" set but "sampling_method" not equal to "GOSS".
# [WARNING 26-08-15 04:56:30.8359 UTC gradient_boosted_trees.cc:1851] "goss_beta" set but "sampling_method" not equal to "GOSS".
# [WARNING 26-08-15 04:56:30.8359 UTC gradient_boosted_trees.cc:1865] "selective_gradient_boosting_ratio" set but "sampling_method" not equal to "SELGB".
# Training dataset read in 0:00:02.721689. Found 3308 examples.
# Training model...
# Model trained in 0:00:00.437265
# Compiling model...
# [INFO 26-08-15 04:56:34.0267 UTC kernel.cc:1233] Loading model from path /tmp/tmp95q6skpe/model/ with prefix 6e5b5abdd6364727
# [INFO 26-08-15 04:56:34.0297 UTC quick_scorer_extended.cc:911] The binary was compiled without AVX2 support, but your CPU supports it. Enable it for faster model inference.
# [INFO 26-08-15 04:56:34.0299 UTC abstract_model.cc:1362] Engine "GradientBoostedTreesQuickScorerExtended" built
# [INFO 26-08-15 04:56:34.0299 UTC kernel.cc:1061] Use fast generic engine
# Model compiled.
# CPU times: user 6.65 s, sys: 507 ms, total: 7.15 s
# Wall time: 6.5 s

# %%
# Evaluate the model
evaluate = model.evaluate(val_ds, return_dict=True)
print()

for name, value in evaluate.items():
    print(f"{name}: {value:.4f}")
# Out:
# WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 1/1 [==============================] - ETA: 0s - loss: 0.0000e+00 - accuracy: 0.9831
# 1/1 [==============================] - 4s 4s/step - loss: 0.0000e+00 - accuracy: 0.9831
# loss: 0.0000
# accuracy: 0.9831

# %%
# Model Summary
model.summary()
# Out:
# Model: "gradient_boosted_trees_model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
# =================================================================
# Total params: 1 (1.00 Byte)
# Trainable params: 0 (0.00 Byte)
# Non-trainable params: 1 (1.00 Byte)
# _________________________________________________________________
# Type: "GRADIENT_BOOSTED_TREES"
# Task: CLASSIFICATION
# Label: "__LABEL"
#
# Input Features (16):
# 	GrayLevelNonUniformity
# 	GrayLevelNonUniformityNormalized
# 	GrayLevelVariance
# 	HighGrayLevelRunEmphasis
# 	LongRunEmphasis
# 	LongRunHighGrayLevelEmphasis
# 	LongRunLowGrayLevelEmphasis
# 	LowGrayLevelRunEmphasis
# 	RunEntropy
# 	RunLengthNonUniformity
# 	RunLengthNonUniformityNormalized
# 	RunPercentage
# 	RunVariance
# 	ShortRunEmphasis
# 	ShortRunHighGrayLevelEmphasis
# 	ShortRunLowGrayLevelEmphasis
#
# Trained with weights
#
# Variable Importance: INV_MEAN_MIN_DEPTH:
#     1.    "ShortRunHighGrayLevelEmphasis"  0.918750 ################
#     2. "GrayLevelNonUniformityNormalized"  0.246824 #
#     3.      "LongRunLowGrayLevelEmphasis"  0.202102
#     4.           "GrayLevelNonUniformity"  0.200345
#     5.                       "RunEntropy"  0.196073
#     6.     "LongRunHighGrayLevelEmphasis"  0.192488
#     7.          "LowGrayLevelRunEmphasis"  0.187765
#     8.     "ShortRunLowGrayLevelEmphasis"  0.186228
#     9.         "HighGrayLevelRunEmphasis"  0.185264
#    10.                 "ShortRunEmphasis"  0.180881
#    11.                  "LongRunEmphasis"  0.180176
#    12.                "GrayLevelVariance"  0.180002
#    13. "RunLengthNonUniformityNormalized"  0.177356
#    14.                      "RunVariance"  0.176893
#    15.                    "RunPercentage"  0.175829
#    16.           "RunLengthNonUniformity"  0.175807
#
# Variable Importance: NUM_AS_ROOT:
#     1. "ShortRunHighGrayLevelEmphasis" 41.000000 ################
#     2.      "HighGrayLevelRunEmphasis"  1.000000
#
# Variable Importance: NUM_NODES:
#     1.    "ShortRunHighGrayLevelEmphasis" 164.000000 ################
#     2.      "LongRunLowGrayLevelEmphasis" 117.000000 ###########
#     3. "GrayLevelNonUniformityNormalized" 106.000000 #########
#     4.           "GrayLevelNonUniformity" 95.000000 ########
#     5.                       "RunEntropy" 81.000000 #######
#     6.     "LongRunHighGrayLevelEmphasis" 78.000000 #######
#     7.          "LowGrayLevelRunEmphasis" 61.000000 #####
#     8.                "GrayLevelVariance" 56.000000 ####
#     9.     "ShortRunLowGrayLevelEmphasis" 53.000000 ####
#    10.         "HighGrayLevelRunEmphasis" 48.000000 ###
#    11.                  "LongRunEmphasis" 26.000000 #
#    12.                 "ShortRunEmphasis" 24.000000 #
#    13.                      "RunVariance" 22.000000 #
#    14. "RunLengthNonUniformityNormalized" 21.000000 #
#    15.                    "RunPercentage" 15.000000
#    16.           "RunLengthNonUniformity" 11.000000
#
# Variable Importance: SUM_SCORE:
#     1.    "ShortRunHighGrayLevelEmphasis" 3260.181864 ################
#     2. "GrayLevelNonUniformityNormalized" 246.106408 #
#     3.          "LowGrayLevelRunEmphasis" 106.260723
#     4.           "GrayLevelNonUniformity" 92.096547
#     5.     "ShortRunLowGrayLevelEmphasis" 70.740992
#     6.      "LongRunLowGrayLevelEmphasis" 48.450590
#     7.                  "LongRunEmphasis" 32.243584
#     8.                       "RunEntropy" 24.458423
#     9.                "GrayLevelVariance" 22.138969
#    10.         "HighGrayLevelRunEmphasis"  9.872741
#    11.     "LongRunHighGrayLevelEmphasis"  8.515847
#    12.                 "ShortRunEmphasis"  8.289217
#    13.                      "RunVariance"  5.236514
#    14.           "RunLengthNonUniformity"  4.305405
#    15. "RunLengthNonUniformityNormalized"  3.119272
#    16.                    "RunPercentage"  0.688003
#
#
#
# Loss: BINOMIAL_LOG_LIKELIHOOD
# Validation loss value: 0.140691
# Number of trees per iteration: 1
# Node format: NOT_SET
# Number of trees: 42
# Total number of nodes: 1998
#
# Number of nodes by tree:
# Count: 42 Average: 47.5714 StdDev: 6.25316
# Min: 29 Max: 59 Ignored: 0
# ----------------------------------------------
# [ 29, 30) 1   2.38%   2.38% #
# [ 30, 32) 0   0.00%   2.38%
# [ 32, 33) 0   0.00%   2.38%
# [ 33, 35) 1   2.38%   4.76% #
# [ 35, 36) 0   0.00%   4.76%
# [ 36, 38) 1   2.38%   7.14% #
# [ 38, 39) 0   0.00%   7.14%
# [ 39, 41) 2   4.76%  11.90% ##
# [ 41, 42) 2   4.76%  16.67% ##
# [ 42, 44) 3   7.14%  23.81% ###
# [ 44, 46) 3   7.14%  30.95% ###
# [ 46, 47) 0   0.00%  30.95%
# [ 47, 49) 9  21.43%  52.38% ##########
# [ 49, 50) 3   7.14%  59.52% ###
# [ 50, 52) 7  16.67%  76.19% ########
# [ 52, 53) 0   0.00%  76.19%
# [ 53, 55) 5  11.90%  88.10% ######
# [ 55, 56) 2   4.76%  92.86% ##
# [ 56, 58) 2   4.76%  97.62% ##
# [ 58, 59] 1   2.38% 100.00% #
#
# Depth by leafs:
# Count: 1020 Average: 4.73627 StdDev: 0.540568
# Min: 2 Max: 5 Ignored: 0
# ----------------------------------------------
# [ 2, 3)   5   0.49%   0.49%
# [ 3, 4)  35   3.43%   3.92%
# [ 4, 5) 184  18.04%  21.96% ##
# [ 5, 5] 796  78.04% 100.00% ##########
#
# Number of training obs by leaf:
# Count: 1020 Average: 123.159 StdDev: 446.452
# Min: 5 Max: 2626 Ignored: 0
# ----------------------------------------------
# [    5,  136) 914  89.61%  89.61% ##########
# [  136,  267)  58   5.69%  95.29% #
# [  267,  398)   5   0.49%  95.78%
# [  398,  529)   1   0.10%  95.88%
# [  529,  660)   0   0.00%  95.88%
# [  660,  791)   0   0.00%  95.88%
# [  791,  922)   0   0.00%  95.88%
# [  922, 1053)   0   0.00%  95.88%
# [ 1053, 1184)   0   0.00%  95.88%
# [ 1184, 1316)   0   0.00%  95.88%
# [ 1316, 1447)   0   0.00%  95.88%
# [ 1447, 1578)   0   0.00%  95.88%
# [ 1578, 1709)   0   0.00%  95.88%
# [ 1709, 1840)   0   0.00%  95.88%
# [ 1840, 1971)   2   0.20%  96.08%
# [ 1971, 2102)   7   0.69%  96.76%
# [ 2102, 2233)   4   0.39%  97.16%
# [ 2233, 2364)  24   2.35%  99.51%
# [ 2364, 2495)   3   0.29%  99.80%
# [ 2495, 2626]   2   0.20% 100.00%
#
# Attribute in nodes:
# 	164 : ShortRunHighGrayLevelEmphasis [NUMERICAL]
# 	117 : LongRunLowGrayLevelEmphasis [NUMERICAL]
# 	106 : GrayLevelNonUniformityNormalized [NUMERICAL]
# 	95 : GrayLevelNonUniformity [NUMERICAL]
# 	81 : RunEntropy [NUMERICAL]
# 	78 : LongRunHighGrayLevelEmphasis [NUMERICAL]
# 	61 : LowGrayLevelRunEmphasis [NUMERICAL]
# 	56 : GrayLevelVariance [NUMERICAL]
# 	53 : ShortRunLowGrayLevelEmphasis [NUMERICAL]
# 	48 : HighGrayLevelRunEmphasis [NUMERICAL]
# 	26 : LongRunEmphasis [NUMERICAL]
# 	24 : ShortRunEmphasis [NUMERICAL]
# 	22 : RunVariance [NUMERICAL]
# 	21 : RunLengthNonUniformityNormalized [NUMERICAL]
# 	15 : RunPercentage [NUMERICAL]
# 	11 : RunLengthNonUniformity [NUMERICAL]
#
# Attribute in nodes with depth <= 0:
# 	41 : ShortRunHighGrayLevelEmphasis [NUMERICAL]
# 	1 : HighGrayLevelRunEmphasis [NUMERICAL]
#
# Attribute in nodes with depth <= 1:
# 	79 : ShortRunHighGrayLevelEmphasis [NUMERICAL]
# 	28 : GrayLevelNonUniformityNormalized [NUMERICAL]
# 	7 : GrayLevelNonUniformity [NUMERICAL]
# 	5 : RunEntropy [NUMERICAL]
# 	2 : ShortRunEmphasis [NUMERICAL]
# 	2 : HighGrayLevelRunEmphasis [NUMERICAL]
# 	1 : LongRunLowGrayLevelEmphasis [NUMERICAL]
# 	1 : LongRunHighGrayLevelEmphasis [NUMERICAL]
# 	1 : LongRunEmphasis [NUMERICAL]
#
# Attribute in nodes with depth <= 2:
# 	101 : ShortRunHighGrayLevelEmphasis [NUMERICAL]
# 	47 : GrayLevelNonUniformityNormalized [NUMERICAL]
# 	35 : GrayLevelNonUniformity [NUMERICAL]
# 	30 : LongRunLowGrayLevelEmphasis [NUMERICAL]
# 	20 : LongRunHighGrayLevelEmphasis [NUMERICAL]
# 	15 : ShortRunLowGrayLevelEmphasis [NUMERICAL]
# 	12 : RunEntropy [NUMERICAL]
# 	10 : LowGrayLevelRunEmphasis [NUMERICAL]
# 	9 : HighGrayLevelRunEmphasis [NUMERICAL]
# 	4 : ShortRunEmphasis [NUMERICAL]
# 	3 : RunLengthNonUniformityNormalized [NUMERICAL]
# 	3 : LongRunEmphasis [NUMERICAL]
#
# Attribute in nodes with depth <= 3:
# 	129 : ShortRunHighGrayLevelEmphasis [NUMERICAL]
# 	68 : GrayLevelNonUniformityNormalized [NUMERICAL]
# 	63 : GrayLevelNonUniformity [NUMERICAL]
# 	60 : LongRunLowGrayLevelEmphasis [NUMERICAL]
# 	47 : LongRunHighGrayLevelEmphasis [NUMERICAL]
# 	43 : RunEntropy [NUMERICAL]
# 	35 : LowGrayLevelRunEmphasis [NUMERICAL]
# 	31 : ShortRunLowGrayLevelEmphasis [NUMERICAL]
# 	24 : GrayLevelVariance [NUMERICAL]
# 	19 : LongRunEmphasis [NUMERICAL]
# 	17 : HighGrayLevelRunEmphasis [NUMERICAL]
# 	16 : ShortRunEmphasis [NUMERICAL]
# 	11 : RunVariance [NUMERICAL]
# 	7 : RunLengthNonUniformityNormalized [NUMERICAL]
# 	6 : RunPercentage [NUMERICAL]
# 	4 : RunLengthNonUniformity [NUMERICAL]
#
# Attribute in nodes with depth <= 5:
# 	164 : ShortRunHighGrayLevelEmphasis [NUMERICAL]
# 	117 : LongRunLowGrayLevelEmphasis [NUMERICAL]
# 	106 : GrayLevelNonUniformityNormalized [NUMERICAL]
# 	95 : GrayLevelNonUniformity [NUMERICAL]
# 	81 : RunEntropy [NUMERICAL]
# 	78 : LongRunHighGrayLevelEmphasis [NUMERICAL]
# 	61 : LowGrayLevelRunEmphasis [NUMERICAL]
# 	56 : GrayLevelVariance [NUMERICAL]
# 	53 : ShortRunLowGrayLevelEmphasis [NUMERICAL]
# 	48 : HighGrayLevelRunEmphasis [NUMERICAL]
# 	26 : LongRunEmphasis [NUMERICAL]
# 	24 : ShortRunEmphasis [NUMERICAL]
# 	22 : RunVariance [NUMERICAL]
# 	21 : RunLengthNonUniformityNormalized [NUMERICAL]
# 	15 : RunPercentage [NUMERICAL]
# 	11 : RunLengthNonUniformity [NUMERICAL]
#
# Condition type in nodes:
# 	978 : HigherCondition
# Condition type in nodes with depth <= 0:
# 	42 : HigherCondition
# Condition type in nodes with depth <= 1:
# 	126 : HigherCondition
# Condition type in nodes with depth <= 2:
# 	289 : HigherCondition
# Condition type in nodes with depth <= 3:
# 	580 : HigherCondition
# Condition type in nodes with depth <= 5:
# 	978 : HigherCondition
#
# Training logs:
# Number of iteration to final model: 42
# 	Iter:1 train-loss:1.200387 valid-loss:1.215922  train-accuracy:0.993153 valid-accuracy:0.957138
# 	Iter:2 train-loss:1.048298 valid-loss:1.075524  train-accuracy:0.993333 valid-accuracy:0.957138
# 	Iter:3 train-loss:0.921486 valid-loss:0.959789  train-accuracy:0.993153 valid-accuracy:0.955627
# 	Iter:4 train-loss:0.814226 valid-loss:0.861716  train-accuracy:0.993513 valid-accuracy:0.955627
# 	Iter:5 train-loss:0.722143 valid-loss:0.777055  train-accuracy:0.993333 valid-accuracy:0.955627
# 	Iter:6 train-loss:0.642547 valid-loss:0.697649  train-accuracy:0.994234 valid-accuracy:0.955627
# 	Iter:16 train-loss:0.226213 valid-loss:0.307982  train-accuracy:0.996937 valid-accuracy:0.961669
# 	Iter:26 train-loss:0.093658 valid-loss:0.180053  train-accuracy:0.997297 valid-accuracy:0.961669
# 	Iter:36 train-loss:0.043045 valid-loss:0.143070  train-accuracy:0.998198 valid-accuracy:0.964690
# 	Iter:46 train-loss:0.022032 valid-loss:0.150674  train-accuracy:0.998739 valid-accuracy:0.964690
# 	Iter:56 train-loss:0.012795 valid-loss:0.166233  train-accuracy:0.999099 valid-accuracy:0.964690
# 	Iter:66 train-loss:0.008011 valid-loss:0.170882  train-accuracy:0.999820 valid-accuracy:0.964690

# %%
# Model features
model.make_inspector().features()
# Out:
# ["GrayLevelNonUniformity" (1; #0),
#  "GrayLevelNonUniformityNormalized" (1; #1),
#  "GrayLevelVariance" (1; #2),
#  "HighGrayLevelRunEmphasis" (1; #3),
#  "LongRunEmphasis" (1; #4),
#  "LongRunHighGrayLevelEmphasis" (1; #5),
#  "LongRunLowGrayLevelEmphasis" (1; #6),
#  "LowGrayLevelRunEmphasis" (1; #7),
#  "RunEntropy" (1; #8),
#  "RunLengthNonUniformity" (1; #9),
#  "RunLengthNonUniformityNormalized" (1; #10),
#  "RunPercentage" (1; #11),
#  "RunVariance" (1; #12),
#  "ShortRunEmphasis" (1; #13),
#  "ShortRunHighGrayLevelEmphasis" (1; #14),
#  "ShortRunLowGrayLevelEmphasis" (1; #15)]

# %%
# Feature importance
model.make_inspector().variable_importances()
# Out:
# {'INV_MEAN_MIN_DEPTH': [("ShortRunHighGrayLevelEmphasis" (1; #14), 0.91875),
#   ("GrayLevelNonUniformityNormalized" (1; #1), 0.24682432497664836),
#   ("LongRunLowGrayLevelEmphasis" (1; #6), 0.2021016534618787),
#   ("GrayLevelNonUniformity" (1; #0), 0.20034524370218995),
#   ("RunEntropy" (1; #8), 0.19607299709311127),
#   ("LongRunHighGrayLevelEmphasis" (1; #5), 0.1924877312330952),
#   ("LowGrayLevelRunEmphasis" (1; #7), 0.1877650059398098),
#   ("ShortRunLowGrayLevelEmphasis" (1; #15), 0.1862278269010869),
#   ("HighGrayLevelRunEmphasis" (1; #3), 0.18526409252075002),
#   ("ShortRunEmphasis" (1; #13), 0.1808810823926213),
#   ("LongRunEmphasis" (1; #4), 0.18017646303005427),
#   ("GrayLevelVariance" (1; #2), 0.18000239386282307),
#   ("RunLengthNonUniformityNormalized" (1; #10), 0.17735613945086745),
#   ("RunVariance" (1; #12), 0.17689344705359264),
#   ("RunPercentage" (1; #11), 0.17582884061588042),
#   ("RunLengthNonUniformity" (1; #9), 0.17580705015139678)],
#  'NUM_AS_ROOT': [("ShortRunHighGrayLevelEmphasis" (1; #14), 41.0),
#   ("HighGrayLevelRunEmphasis" (1; #3), 1.0)],
#  'SUM_SCORE': [("ShortRunHighGrayLevelEmphasis" (1; #14), 3260.1818635658333),
#   ("GrayLevelNonUniformityNormalized" (1; #1), 246.1064084758976),
#   ("LowGrayLevelRunEmphasis" (1; #7), 106.26072270811014),
#   ("GrayLevelNonUniformity" (1; #0), 92.09654709867006),
#   ("ShortRunLowGrayLevelEmphasis" (1; #15), 70.74099154214748),
#   ("LongRunLowGrayLevelEmphasis" (1; #6), 48.450589610463346),
#   ("LongRunEmphasis" (1; #4), 32.243584449810584),
#   ("RunEntropy" (1; #8), 24.458423250826815),
#   ("GrayLevelVariance" (1; #2), 22.138968667903708),
#   ("HighGrayLevelRunEmphasis" (1; #3), 9.872741087633539),
#   ("LongRunHighGrayLevelEmphasis" (1; #5), 8.515846919123149),
#   ("ShortRunEmphasis" (1; #13), 8.289217471078548),
#   ("RunVariance" (1; #12), 5.236514140276094),
#   ("RunLengthNonUniformity" (1; #9), 4.305404959925755),
#   ("RunLengthNonUniformityNormalized" (1; #10), 3.119272316145761),
#   ("RunPercentage" (1; #11), 0.6880027541182298)],
#  'NUM_NODES': [("ShortRunHighGrayLevelEmphasis" (1; #14), 164.0),
#   ("LongRunLowGrayLevelEmphasis" (1; #6), 117.0),
#   ("GrayLevelNonUniformityNormalized" (1; #1), 106.0),
#   ("GrayLevelNonUniformity" (1; #0), 95.0),
#   ("RunEntropy" (1; #8), 81.0),
#   ("LongRunHighGrayLevelEmphasis" (1; #5), 78.0),
#   ("LowGrayLevelRunEmphasis" (1; #7), 61.0),
#   ("GrayLevelVariance" (1; #2), 56.0),
#   ("ShortRunLowGrayLevelEmphasis" (1; #15), 53.0),
#   ("HighGrayLevelRunEmphasis" (1; #3), 48.0),
#   ("LongRunEmphasis" (1; #4), 26.0),
#   ("ShortRunEmphasis" (1; #13), 24.0),
#   ("RunVariance" (1; #12), 22.0),
#   ("RunLengthNonUniformityNormalized" (1; #10), 21.0),
#   ("RunPercentage" (1; #11), 15.0),
#   ("RunLengthNonUniformity" (1; #9), 11.0)]}

# %%
# Model self evaluation
model.make_inspector().evaluation()
# Out:
# Evaluation(num_examples=None, accuracy=0.9646900296211243, loss=0.14069122076034546, rmse=None, ndcg=None, aucs=None, auuc=None, qini=None)

# %%
logs = model.make_inspector().training_logs()

plt.figure(figsize=(12, 4))
plt.subplot(1, 2, 1)
plt.plot([log.num_trees for log in logs], [log.evaluation.accuracy for log in logs])
plt.xlabel("Number of trees")
plt.ylabel("Accuracy (out-of-bag)")
plt.subplot(1, 2, 2)
plt.plot([log.num_trees for log in logs], [log.evaluation.loss for log in logs])
plt.xlabel("Number of trees")
plt.ylabel("Logloss (out-of-bag)")
plt.show()

# %% [markdown]
# Calculate the score of our hold-out validation dataset

# %%
predictions = model.predict(val_ds)
y_true      = validation_data["label"]

from sklearn.metrics import roc_auc_score
ROC_AUC = roc_auc_score(y_true, predictions)
print("The ROC AUC score is %.5f" % ROC_AUC )
# Out:
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 64ms/step
# The ROC AUC score is 0.99535

# %%
# Compute binary classification metrics with sklearn
import numpy as np
from sklearn.metrics import (
    accuracy_score,
    precision_score,
    recall_score,
    f1_score,
    roc_auc_score,
    average_precision_score,
    confusion_matrix,
    classification_report,
    matthews_corrcoef,
    log_loss,
    brier_score_loss,
)

# Get predictions (probabilities or class labels)
preds = model.predict(test_ds)
# If model outputs probabilities, convert to labels by threshold 0.5
if preds.ndim == 2:
    # For TFDF classification, preds may be class probabilities with shape (N, 2)
    if preds.shape[1] == 2:
        pos_probs = preds[:, 1]
    else:
        # If single-probability column (positive class)
        pos_probs = preds[:, -1]
    y_pred = (pos_probs >= 0.5).astype(int)
else:
    # Already class labels
    y_pred = preds.astype(int)
    pos_probs = None

# Ground truth labels (must be 0/1 integers)
y_true = test_data["label"].astype(int).to_numpy()

# Core metrics
metrics = {}
metrics["accuracy"] = accuracy_score(y_true, y_pred)
metrics["precision"] = precision_score(y_true, y_pred, zero_division=0)
metrics["recall"] = recall_score(y_true, y_pred, zero_division=0)
metrics["f1"] = f1_score(y_true, y_pred, zero_division=0)
metrics["mcc"] = matthews_corrcoef(y_true, y_pred)

# Probabilistic metrics (only if we have probabilities)
if pos_probs is not None:
    metrics["roc_auc"] = roc_auc_score(y_true, pos_probs)
    metrics["pr_auc"] = average_precision_score(y_true, pos_probs)
    metrics["log_loss"] = log_loss(y_true, pos_probs, labels=[0,1])
    metrics["brier_score"] = brier_score_loss(y_true, pos_probs)

# Confusion matrix and detailed report
cm = confusion_matrix(y_true, y_pred, labels=[0,1])
report = classification_report(y_true, y_pred, digits=4)

print("Sklearn binary metrics:")
for k, v in metrics.items():
    print(f"{k}: {v:.4f}")
print("\nConfusion matrix:\n", cm)
print("\nClassification report:\n", report)
# Out:
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 81ms/step
# Sklearn binary metrics:
# accuracy: 0.9831
# precision: 0.8000
# recall: 0.9231
# f1: 0.8571
# mcc: 0.8507
# roc_auc: 0.9859
# pr_auc: 0.9596
# log_loss: 0.0498
# brier_score: 0.0132
#
# Confusion matrix:
#  [[882  12]
#  [  4  48]]
#
# Classification report:
#                precision    recall  f1-score   support
#
#            0     0.9955    0.9866    0.9910       894
#            1     0.8000    0.9231    0.8571        52
#
#     accuracy                         0.9831       946
#    macro avg     0.8977    0.9548    0.9241       946
# weighted avg     0.9847    0.9831    0.9837       946
