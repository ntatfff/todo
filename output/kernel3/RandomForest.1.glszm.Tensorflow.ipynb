# %%
# Import packages and modules
import numpy  as np
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow_decision_forests as tfdf

from sklearn.model_selection import train_test_split
# Out:
# 2026-08-15 05:11:29.107583: I tensorflow/core/util/port.cc:113] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2026-08-15 05:11:29.457543: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2026-08-15 05:11:34.126326: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
# Check the version of TensorFlow Decision Forests
print("Found TensorFlow Decision Forests v" + tfdf.__version__)
# Out:
# Found TensorFlow Decision Forests v1.9.1

# %%
datasetPath = 'dataset/firstorder/kernel5/dataset.csv'

# %%
# Parameters
datasetPath = "dataset/glszm/kernel3/1.dataset.csv"

# %%
# train/validation/test = 70/10/20
dataset = pd.read_csv(datasetPath)

train_data, temp_data = train_test_split(dataset, test_size=0.3, random_state=42)
validation_data, test_data = train_test_split(temp_data, test_size=2/3, random_state=42)

# %%
from sklearn.utils.class_weight import compute_class_weight

# tinh class weight tren tap train
classes = np.array([0, 1])
weights = compute_class_weight(class_weight="balanced", classes=classes, y=train_data["label"])
class_weight = {0: weights[0], 1: weights[1]}

# gan sample_weight cho tung dong
train_data["sample_weight"] = train_data["label"].map(class_weight)
validation_data["sample_weight"] = validation_data["label"].map(class_weight)
test_data["sample_weight"] = test_data["label"].map(class_weight)

# Convert the dataset into a TensorFlow dataset.
train_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    train_data, label="label", weight="sample_weight"
)         
val_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    validation_data, label="label", weight="sample_weight"
)
test_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    test_data, label="label", weight="sample_weight"
)
# Out:
# 2026-08-15 05:11:47.105041: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:984] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2026-08-15 05:11:47.106301: W tensorflow/core/common_runtime/gpu/gpu_device.cc:2251] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...

# %%
import keras

# %%
# %%time

# Train a Random Forest model.
model = tfdf.keras.RandomForestModel()

# Add evaluation metrics
model.compile(
    metrics=["accuracy"]
)
model.fit(x=train_ds)

# # Train a Gradient Boosted Trees model.
# model = tfdf.keras.GradientBoostedTreesModel(num_trees=1500)
# model.fit(train_ds)
# Out:
# Use /tmp/tmpyjw3zcns as temporary training directory
# Reading training dataset...
# Training dataset read in 0:00:02.565981. Found 3308 examples.
# Training model...
# Model trained in 0:00:00.112355
# Compiling model...
# [INFO 26-08-15 05:11:49.9435 UTC kernel.cc:1233] Loading model from path /tmp/tmpyjw3zcns/model/ with prefix 220964e5ae264c36
# [INFO 26-08-15 05:11:49.9607 UTC decision_forest.cc:734] Model loaded with 300 root(s), 13638 node(s), and 16 input feature(s).
# [INFO 26-08-15 05:11:49.9607 UTC abstract_model.cc:1362] Engine "RandomForestOptPred" built
# [INFO 26-08-15 05:11:49.9607 UTC kernel.cc:1061] Use fast generic engine
# Model compiled.
# CPU times: user 6 s, sys: 113 ms, total: 6.11 s
# Wall time: 5.84 s

# %%
# Evaluate the model
evaluate = model.evaluate(val_ds, return_dict=True)
print()

for name, value in evaluate.items():
    print(f"{name}: {value:.4f}")
# Out:
# WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 1/1 [==============================] - ETA: 0s - loss: 0.0000e+00 - accuracy: 0.9937
# 1/1 [==============================] - 3s 3s/step - loss: 0.0000e+00 - accuracy: 0.9937
# loss: 0.0000
# accuracy: 0.9937

# %%
# Model Summary
model.summary()
# Out:
# Model: "random_forest_model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
# =================================================================
# Total params: 1 (1.00 Byte)
# Trainable params: 0 (0.00 Byte)
# Non-trainable params: 1 (1.00 Byte)
# _________________________________________________________________
# Type: "RANDOM_FOREST"
# Task: CLASSIFICATION
# Label: "__LABEL"
#
# Input Features (16):
# 	GrayLevelNonUniformity
# 	GrayLevelNonUniformityNormalized
# 	GrayLevelVariance
# 	HighGrayLevelZoneEmphasis
# 	LargeAreaEmphasis
# 	LargeAreaHighGrayLevelEmphasis
# 	LargeAreaLowGrayLevelEmphasis
# 	LowGrayLevelZoneEmphasis
# 	SizeZoneNonUniformity
# 	SizeZoneNonUniformityNormalized
# 	SmallAreaEmphasis
# 	SmallAreaHighGrayLevelEmphasis
# 	SmallAreaLowGrayLevelEmphasis
# 	ZoneEntropy
# 	ZonePercentage
# 	ZoneVariance
#
# Trained with weights
#
# Variable Importance: INV_MEAN_MIN_DEPTH:
#     1.   "SmallAreaHighGrayLevelEmphasis"  0.262437 ################
#     2.        "HighGrayLevelZoneEmphasis"  0.252357 ##############
#     3.         "LowGrayLevelZoneEmphasis"  0.234495 ###########
#     4.    "LargeAreaLowGrayLevelEmphasis"  0.200737 ######
#     5.    "SmallAreaLowGrayLevelEmphasis"  0.193864 #####
#     6.                      "ZoneEntropy"  0.192375 #####
#     7.           "GrayLevelNonUniformity"  0.187375 ####
#     8. "GrayLevelNonUniformityNormalized"  0.183491 ####
#     9.                "LargeAreaEmphasis"  0.172240 ##
#    10.                "GrayLevelVariance"  0.172138 ##
#    11.                     "ZoneVariance"  0.164156 #
#    12.                   "ZonePercentage"  0.162644
#    13.   "LargeAreaHighGrayLevelEmphasis"  0.162124
#    14.            "SizeZoneNonUniformity"  0.159180
#    15.  "SizeZoneNonUniformityNormalized"  0.156958
#    16.                "SmallAreaEmphasis"  0.156284
#
# Variable Importance: NUM_AS_ROOT:
#     1.        "HighGrayLevelZoneEmphasis" 82.000000 ################
#     2.   "SmallAreaHighGrayLevelEmphasis" 80.000000 ###############
#     3.         "LowGrayLevelZoneEmphasis" 51.000000 #########
#     4.    "SmallAreaLowGrayLevelEmphasis" 35.000000 ######
#     5.    "LargeAreaLowGrayLevelEmphasis" 25.000000 ####
#     6.                      "ZoneEntropy"  9.000000 #
#     7. "GrayLevelNonUniformityNormalized"  5.000000
#     8.                "GrayLevelVariance"  4.000000
#     9.                "LargeAreaEmphasis"  4.000000
#    10.                     "ZoneVariance"  3.000000
#    11.                   "ZonePercentage"  2.000000
#
# Variable Importance: NUM_NODES:
#     1.         "LowGrayLevelZoneEmphasis" 710.000000 ################
#     2.        "HighGrayLevelZoneEmphasis" 703.000000 ###############
#     3.   "SmallAreaHighGrayLevelEmphasis" 649.000000 ##############
#     4.           "GrayLevelNonUniformity" 561.000000 ###########
#     5.    "LargeAreaLowGrayLevelEmphasis" 537.000000 ##########
#     6.                      "ZoneEntropy" 508.000000 #########
#     7.    "SmallAreaLowGrayLevelEmphasis" 445.000000 #######
#     8. "GrayLevelNonUniformityNormalized" 433.000000 #######
#     9.                "LargeAreaEmphasis" 340.000000 ####
#    10.                "GrayLevelVariance" 336.000000 ####
#    11.                     "ZoneVariance" 302.000000 ###
#    12.   "LargeAreaHighGrayLevelEmphasis" 274.000000 ##
#    13.                   "ZonePercentage" 240.000000 #
#    14.            "SizeZoneNonUniformity" 230.000000 #
#    15.  "SizeZoneNonUniformityNormalized" 206.000000
#    16.                "SmallAreaEmphasis" 195.000000
#
# Variable Importance: SUM_SCORE:
#     1.   "SmallAreaHighGrayLevelEmphasis" 172423.608253 ################
#     2.        "HighGrayLevelZoneEmphasis" 168428.209373 ###############
#     3.         "LowGrayLevelZoneEmphasis" 113356.057091 ##########
#     4.    "SmallAreaLowGrayLevelEmphasis" 58533.169885 #####
#     5.    "LargeAreaLowGrayLevelEmphasis" 43482.931672 ###
#     6.                      "ZoneEntropy" 31416.829434 ##
#     7. "GrayLevelNonUniformityNormalized" 21577.120144 #
#     8.           "GrayLevelNonUniformity" 16826.605841 #
#     9.                "GrayLevelVariance" 12416.795408
#    10.                "LargeAreaEmphasis" 10587.305517
#    11.                     "ZoneVariance" 6416.493334
#    12.                   "ZonePercentage" 5910.187733
#    13.   "LargeAreaHighGrayLevelEmphasis" 5089.176255
#    14.            "SizeZoneNonUniformity" 2914.428856
#    15.  "SizeZoneNonUniformityNormalized" 2172.442716
#    16.                "SmallAreaEmphasis" 1899.338098
#
#
#
# Winner takes all: true
# Out-of-bag evaluation: accuracy:0.951397 logloss:0.113399
# Number of trees: 300
# Total number of nodes: 13638
#
# Number of nodes by tree:
# Count: 300 Average: 45.46 StdDev: 5.26261
# Min: 31 Max: 61 Ignored: 0
# ----------------------------------------------
# [ 31, 32)  2   0.67%   0.67%
# [ 32, 34)  1   0.33%   1.00%
# [ 34, 35)  0   0.00%   1.00%
# [ 35, 37)  5   1.67%   2.67% #
# [ 37, 38) 16   5.33%   8.00% ###
# [ 38, 40) 18   6.00%  14.00% ####
# [ 40, 41)  0   0.00%  14.00%
# [ 41, 43) 39  13.00%  27.00% ########
# [ 43, 44) 40  13.33%  40.33% ########
# [ 44, 46) 38  12.67%  53.00% ########
# [ 46, 48) 48  16.00%  69.00% ##########
# [ 48, 49)  0   0.00%  69.00%
# [ 49, 51) 38  12.67%  81.67% ########
# [ 51, 52) 26   8.67%  90.33% #####
# [ 52, 54) 10   3.33%  93.67% ##
# [ 54, 55)  0   0.00%  93.67%
# [ 55, 57)  9   3.00%  96.67% ##
# [ 57, 58)  8   2.67%  99.33% ##
# [ 58, 60)  1   0.33%  99.67%
# [ 60, 61]  1   0.33% 100.00%
#
# Depth by leafs:
# Count: 6969 Average: 5.59937 StdDev: 2.00721
# Min: 2 Max: 15 Ignored: 0
# ----------------------------------------------
# [  2,  3)  220   3.16%   3.16% #
# [  3,  4)  728  10.45%  13.60% #####
# [  4,  5) 1232  17.68%  31.28% ########
# [  5,  6) 1515  21.74%  53.02% ##########
# [  6,  7) 1295  18.58%  71.60% #########
# [  7,  8)  844  12.11%  83.71% ######
# [  8,  9)  513   7.36%  91.07% ###
# [  9, 10)  299   4.29%  95.37% ##
# [ 10, 11)  191   2.74%  98.11% #
# [ 11, 12)   98   1.41%  99.51% #
# [ 12, 13)   19   0.27%  99.78%
# [ 13, 14)    6   0.09%  99.87%
# [ 14, 15)    7   0.10%  99.97%
# [ 15, 15]    2   0.03% 100.00%
#
# Number of training obs by leaf:
# Count: 6969 Average: 142.402 StdDev: 487.464
# Min: 5 Max: 2835 Ignored: 0
# ----------------------------------------------
# [    5,  146) 6216  89.20%  89.20% ##########
# [  146,  288)  241   3.46%  92.65%
# [  288,  429)  113   1.62%  94.27%
# [  429,  571)   56   0.80%  95.08%
# [  571,  712)   23   0.33%  95.41%
# [  712,  854)   11   0.16%  95.57%
# [  854,  995)    6   0.09%  95.65%
# [  995, 1137)    3   0.04%  95.70%
# [ 1137, 1278)    1   0.01%  95.71%
# [ 1278, 1420)    3   0.04%  95.75%
# [ 1420, 1562)    3   0.04%  95.80%
# [ 1562, 1703)    4   0.06%  95.85%
# [ 1703, 1845)    6   0.09%  95.94%
# [ 1845, 1986)    7   0.10%  96.04%
# [ 1986, 2128)   14   0.20%  96.24%
# [ 2128, 2269)   25   0.36%  96.60%
# [ 2269, 2411)   69   0.99%  97.59%
# [ 2411, 2552)   93   1.33%  98.92%
# [ 2552, 2694)   61   0.88%  99.80%
# [ 2694, 2835]   14   0.20% 100.00%
#
# Attribute in nodes:
# 	710 : LowGrayLevelZoneEmphasis [NUMERICAL]
# 	703 : HighGrayLevelZoneEmphasis [NUMERICAL]
# 	649 : SmallAreaHighGrayLevelEmphasis [NUMERICAL]
# 	561 : GrayLevelNonUniformity [NUMERICAL]
# 	537 : LargeAreaLowGrayLevelEmphasis [NUMERICAL]
# 	508 : ZoneEntropy [NUMERICAL]
# 	445 : SmallAreaLowGrayLevelEmphasis [NUMERICAL]
# 	433 : GrayLevelNonUniformityNormalized [NUMERICAL]
# 	340 : LargeAreaEmphasis [NUMERICAL]
# 	336 : GrayLevelVariance [NUMERICAL]
# 	302 : ZoneVariance [NUMERICAL]
# 	274 : LargeAreaHighGrayLevelEmphasis [NUMERICAL]
# 	240 : ZonePercentage [NUMERICAL]
# 	230 : SizeZoneNonUniformity [NUMERICAL]
# 	206 : SizeZoneNonUniformityNormalized [NUMERICAL]
# 	195 : SmallAreaEmphasis [NUMERICAL]
#
# Attribute in nodes with depth <= 0:
# 	82 : HighGrayLevelZoneEmphasis [NUMERICAL]
# 	80 : SmallAreaHighGrayLevelEmphasis [NUMERICAL]
# 	51 : LowGrayLevelZoneEmphasis [NUMERICAL]
# 	35 : SmallAreaLowGrayLevelEmphasis [NUMERICAL]
# 	25 : LargeAreaLowGrayLevelEmphasis [NUMERICAL]
# 	9 : ZoneEntropy [NUMERICAL]
# 	5 : GrayLevelNonUniformityNormalized [NUMERICAL]
# 	4 : LargeAreaEmphasis [NUMERICAL]
# 	4 : GrayLevelVariance [NUMERICAL]
# 	3 : ZoneVariance [NUMERICAL]
# 	2 : ZonePercentage [NUMERICAL]
#
# Attribute in nodes with depth <= 1:
# 	200 : SmallAreaHighGrayLevelEmphasis [NUMERICAL]
# 	192 : HighGrayLevelZoneEmphasis [NUMERICAL]
# 	116 : LowGrayLevelZoneEmphasis [NUMERICAL]
# 	78 : ZoneEntropy [NUMERICAL]
# 	72 : LargeAreaLowGrayLevelEmphasis [NUMERICAL]
# 	61 : SmallAreaLowGrayLevelEmphasis [NUMERICAL]
# 	55 : GrayLevelNonUniformityNormalized [NUMERICAL]
# 	31 : GrayLevelNonUniformity [NUMERICAL]
# 	30 : LargeAreaEmphasis [NUMERICAL]
# 	26 : GrayLevelVariance [NUMERICAL]
# 	16 : ZonePercentage [NUMERICAL]
# 	12 : ZoneVariance [NUMERICAL]
# 	8 : LargeAreaHighGrayLevelEmphasis [NUMERICAL]
# 	1 : SmallAreaEmphasis [NUMERICAL]
# 	1 : SizeZoneNonUniformityNormalized [NUMERICAL]
# 	1 : SizeZoneNonUniformity [NUMERICAL]
#
# Attribute in nodes with depth <= 2:
# 	323 : SmallAreaHighGrayLevelEmphasis [NUMERICAL]
# 	321 : HighGrayLevelZoneEmphasis [NUMERICAL]
# 	264 : LowGrayLevelZoneEmphasis [NUMERICAL]
# 	161 : ZoneEntropy [NUMERICAL]
# 	145 : LargeAreaLowGrayLevelEmphasis [NUMERICAL]
# 	131 : SmallAreaLowGrayLevelEmphasis [NUMERICAL]
# 	122 : GrayLevelNonUniformity [NUMERICAL]
# 	119 : GrayLevelNonUniformityNormalized [NUMERICAL]
# 	91 : GrayLevelVariance [NUMERICAL]
# 	57 : LargeAreaEmphasis [NUMERICAL]
# 	35 : ZonePercentage [NUMERICAL]
# 	34 : ZoneVariance [NUMERICAL]
# 	34 : LargeAreaHighGrayLevelEmphasis [NUMERICAL]
# 	21 : SizeZoneNonUniformity [NUMERICAL]
# 	13 : SizeZoneNonUniformityNormalized [NUMERICAL]
# 	9 : SmallAreaEmphasis [NUMERICAL]
#
# Attribute in nodes with depth <= 3:
# 	446 : HighGrayLevelZoneEmphasis [NUMERICAL]
# 	418 : SmallAreaHighGrayLevelEmphasis [NUMERICAL]
# 	408 : LowGrayLevelZoneEmphasis [NUMERICAL]
# 	261 : LargeAreaLowGrayLevelEmphasis [NUMERICAL]
# 	255 : GrayLevelNonUniformity [NUMERICAL]
# 	251 : ZoneEntropy [NUMERICAL]
# 	219 : SmallAreaLowGrayLevelEmphasis [NUMERICAL]
# 	193 : GrayLevelNonUniformityNormalized [NUMERICAL]
# 	147 : GrayLevelVariance [NUMERICAL]
# 	117 : LargeAreaEmphasis [NUMERICAL]
# 	87 : LargeAreaHighGrayLevelEmphasis [NUMERICAL]
# 	79 : ZoneVariance [NUMERICAL]
# 	75 : ZonePercentage [NUMERICAL]
# 	66 : SizeZoneNonUniformity [NUMERICAL]
# 	52 : SizeZoneNonUniformityNormalized [NUMERICAL]
# 	38 : SmallAreaEmphasis [NUMERICAL]
#
# Attribute in nodes with depth <= 5:
# 	613 : HighGrayLevelZoneEmphasis [NUMERICAL]
# 	601 : LowGrayLevelZoneEmphasis [NUMERICAL]
# 	571 : SmallAreaHighGrayLevelEmphasis [NUMERICAL]
# 	442 : LargeAreaLowGrayLevelEmphasis [NUMERICAL]
# 	442 : GrayLevelNonUniformity [NUMERICAL]
# 	401 : ZoneEntropy [NUMERICAL]
# 	359 : SmallAreaLowGrayLevelEmphasis [NUMERICAL]
# 	336 : GrayLevelNonUniformityNormalized [NUMERICAL]
# 	261 : LargeAreaEmphasis [NUMERICAL]
# 	254 : GrayLevelVariance [NUMERICAL]
# 	213 : ZoneVariance [NUMERICAL]
# 	191 : LargeAreaHighGrayLevelEmphasis [NUMERICAL]
# 	165 : ZonePercentage [NUMERICAL]
# 	162 : SizeZoneNonUniformity [NUMERICAL]
# 	141 : SmallAreaEmphasis [NUMERICAL]
# 	141 : SizeZoneNonUniformityNormalized [NUMERICAL]
#
# Condition type in nodes:
# 	6669 : HigherCondition
# Condition type in nodes with depth <= 0:
# 	300 : HigherCondition
# Condition type in nodes with depth <= 1:
# 	900 : HigherCondition
# Condition type in nodes with depth <= 2:
# 	1880 : HigherCondition
# Condition type in nodes with depth <= 3:
# 	3112 : HigherCondition
# Condition type in nodes with depth <= 5:
# 	5293 : HigherCondition
# Node format: NOT_SET
#
# Training OOB:
# 	trees: 1, Out-of-bag evaluation: accuracy:0.885424 logloss:4.12974
# 	trees: 12, Out-of-bag evaluation: accuracy:0.923686 logloss:1.16924
# 	trees: 22, Out-of-bag evaluation: accuracy:0.941015 logloss:0.572242
# 	trees: 32, Out-of-bag evaluation: accuracy:0.941025 logloss:0.393189
# 	trees: 43, Out-of-bag evaluation: accuracy:0.945728 logloss:0.214199
# 	trees: 55, Out-of-bag evaluation: accuracy:0.946211 logloss:0.213189
# 	trees: 65, Out-of-bag evaluation: accuracy:0.946371 logloss:0.203591
# 	trees: 75, Out-of-bag evaluation: accuracy:0.948241 logloss:0.203374
# 	trees: 85, Out-of-bag evaluation: accuracy:0.948402 logloss:0.195861
# 	trees: 95, Out-of-bag evaluation: accuracy:0.951075 logloss:0.192825
# 	trees: 105, Out-of-bag evaluation: accuracy:0.951397 logloss:0.189606
# 	trees: 115, Out-of-bag evaluation: accuracy:0.949045 logloss:0.189078
# 	trees: 125, Out-of-bag evaluation: accuracy:0.948723 logloss:0.188532
# 	trees: 135, Out-of-bag evaluation: accuracy:0.948562 logloss:0.187193
# 	trees: 145, Out-of-bag evaluation: accuracy:0.948723 logloss:0.187784
# 	trees: 155, Out-of-bag evaluation: accuracy:0.946211 logloss:0.186011
# 	trees: 165, Out-of-bag evaluation: accuracy:0.946211 logloss:0.186817
# 	trees: 175, Out-of-bag evaluation: accuracy:0.948723 logloss:0.186846
# 	trees: 185, Out-of-bag evaluation: accuracy:0.948723 logloss:0.186846
# 	trees: 195, Out-of-bag evaluation: accuracy:0.951397 logloss:0.187855
# 	trees: 205, Out-of-bag evaluation: accuracy:0.951397 logloss:0.18844
# 	trees: 215, Out-of-bag evaluation: accuracy:0.951236 logloss:0.188842
# 	trees: 225, Out-of-bag evaluation: accuracy:0.951397 logloss:0.189444
# 	trees: 235, Out-of-bag evaluation: accuracy:0.951236 logloss:0.1901
# 	trees: 245, Out-of-bag evaluation: accuracy:0.951397 logloss:0.191399
# 	trees: 255, Out-of-bag evaluation: accuracy:0.948884 logloss:0.112461
# 	trees: 265, Out-of-bag evaluation: accuracy:0.951397 logloss:0.112796
# 	trees: 276, Out-of-bag evaluation: accuracy:0.949045 logloss:0.112867
# 	trees: 286, Out-of-bag evaluation: accuracy:0.951397 logloss:0.112748
# 	trees: 296, Out-of-bag evaluation: accuracy:0.951397 logloss:0.113053
# 	trees: 300, Out-of-bag evaluation: accuracy:0.951397 logloss:0.113399

# %%
# Model features
model.make_inspector().features()
# Out:
# ["GrayLevelNonUniformity" (1; #0),
#  "GrayLevelNonUniformityNormalized" (1; #1),
#  "GrayLevelVariance" (1; #2),
#  "HighGrayLevelZoneEmphasis" (1; #3),
#  "LargeAreaEmphasis" (1; #4),
#  "LargeAreaHighGrayLevelEmphasis" (1; #5),
#  "LargeAreaLowGrayLevelEmphasis" (1; #6),
#  "LowGrayLevelZoneEmphasis" (1; #7),
#  "SizeZoneNonUniformity" (1; #8),
#  "SizeZoneNonUniformityNormalized" (1; #9),
#  "SmallAreaEmphasis" (1; #10),
#  "SmallAreaHighGrayLevelEmphasis" (1; #11),
#  "SmallAreaLowGrayLevelEmphasis" (1; #12),
#  "ZoneEntropy" (1; #13),
#  "ZonePercentage" (1; #14),
#  "ZoneVariance" (1; #15)]

# %%
# Feature importance
model.make_inspector().variable_importances()
# Out:
# {'INV_MEAN_MIN_DEPTH': [("SmallAreaHighGrayLevelEmphasis" (1; #11),
#    0.26243732828916316),
#   ("HighGrayLevelZoneEmphasis" (1; #3), 0.2523572577107132),
#   ("LowGrayLevelZoneEmphasis" (1; #7), 0.23449526138814178),
#   ("LargeAreaLowGrayLevelEmphasis" (1; #6), 0.20073695632061778),
#   ("SmallAreaLowGrayLevelEmphasis" (1; #12), 0.1938643621186226),
#   ("ZoneEntropy" (1; #13), 0.19237514867817004),
#   ("GrayLevelNonUniformity" (1; #0), 0.18737477643908995),
#   ("GrayLevelNonUniformityNormalized" (1; #1), 0.183491336884039),
#   ("LargeAreaEmphasis" (1; #4), 0.17224032937107953),
#   ("GrayLevelVariance" (1; #2), 0.1721381685067525),
#   ("ZoneVariance" (1; #15), 0.16415573509899078),
#   ("ZonePercentage" (1; #14), 0.16264422248741744),
#   ("LargeAreaHighGrayLevelEmphasis" (1; #5), 0.1621237083550582),
#   ("SizeZoneNonUniformity" (1; #8), 0.15917982145200746),
#   ("SizeZoneNonUniformityNormalized" (1; #9), 0.15695817641696796),
#   ("SmallAreaEmphasis" (1; #10), 0.15628404058961898)],
#  'NUM_AS_ROOT': [("HighGrayLevelZoneEmphasis" (1; #3), 82.0),
#   ("SmallAreaHighGrayLevelEmphasis" (1; #11), 80.0),
#   ("LowGrayLevelZoneEmphasis" (1; #7), 51.0),
#   ("SmallAreaLowGrayLevelEmphasis" (1; #12), 35.0),
#   ("LargeAreaLowGrayLevelEmphasis" (1; #6), 25.0),
#   ("ZoneEntropy" (1; #13), 9.0),
#   ("GrayLevelNonUniformityNormalized" (1; #1), 5.0),
#   ("GrayLevelVariance" (1; #2), 4.0),
#   ("LargeAreaEmphasis" (1; #4), 4.0),
#   ("ZoneVariance" (1; #15), 3.0),
#   ("ZonePercentage" (1; #14), 2.0)],
#  'SUM_SCORE': [("SmallAreaHighGrayLevelEmphasis" (1; #11), 172423.60825286596),
#   ("HighGrayLevelZoneEmphasis" (1; #3), 168428.20937336204),
#   ("LowGrayLevelZoneEmphasis" (1; #7), 113356.05709095071),
#   ("SmallAreaLowGrayLevelEmphasis" (1; #12), 58533.169884832845),
#   ("LargeAreaLowGrayLevelEmphasis" (1; #6), 43482.931671784485),
#   ("ZoneEntropy" (1; #13), 31416.829434334562),
#   ("GrayLevelNonUniformityNormalized" (1; #1), 21577.120144425884),
#   ("GrayLevelNonUniformity" (1; #0), 16826.60584111446),
#   ("GrayLevelVariance" (1; #2), 12416.795407661597),
#   ("LargeAreaEmphasis" (1; #4), 10587.30551692539),
#   ("ZoneVariance" (1; #15), 6416.493333891705),
#   ("ZonePercentage" (1; #14), 5910.187733030061),
#   ("LargeAreaHighGrayLevelEmphasis" (1; #5), 5089.176254621535),
#   ("SizeZoneNonUniformity" (1; #8), 2914.4288564706544),
#   ("SizeZoneNonUniformityNormalized" (1; #9), 2172.442715725089),
#   ("SmallAreaEmphasis" (1; #10), 1899.3380977979782)],
#  'NUM_NODES': [("LowGrayLevelZoneEmphasis" (1; #7), 710.0),
#   ("HighGrayLevelZoneEmphasis" (1; #3), 703.0),
#   ("SmallAreaHighGrayLevelEmphasis" (1; #11), 649.0),
#   ("GrayLevelNonUniformity" (1; #0), 561.0),
#   ("LargeAreaLowGrayLevelEmphasis" (1; #6), 537.0),
#   ("ZoneEntropy" (1; #13), 508.0),
#   ("SmallAreaLowGrayLevelEmphasis" (1; #12), 445.0),
#   ("GrayLevelNonUniformityNormalized" (1; #1), 433.0),
#   ("LargeAreaEmphasis" (1; #4), 340.0),
#   ("GrayLevelVariance" (1; #2), 336.0),
#   ("ZoneVariance" (1; #15), 302.0),
#   ("LargeAreaHighGrayLevelEmphasis" (1; #5), 274.0),
#   ("ZonePercentage" (1; #14), 240.0),
#   ("SizeZoneNonUniformity" (1; #8), 230.0),
#   ("SizeZoneNonUniformityNormalized" (1; #9), 206.0),
#   ("SmallAreaEmphasis" (1; #10), 195.0)]}

# %%
# Model self evaluation
model.make_inspector().evaluation()
# Out:
# Evaluation(num_examples=3308, accuracy=0.951396578439492, loss=0.11339933301148915, rmse=None, ndcg=None, aucs=None, auuc=None, qini=None)

# %%
logs = model.make_inspector().training_logs()

plt.figure(figsize=(12, 4))
plt.subplot(1, 2, 1)
plt.plot([log.num_trees for log in logs], [log.evaluation.accuracy for log in logs])
plt.xlabel("Number of trees")
plt.ylabel("Accuracy (out-of-bag)")
plt.subplot(1, 2, 2)
plt.plot([log.num_trees for log in logs], [log.evaluation.loss for log in logs])
plt.xlabel("Number of trees")
plt.ylabel("Logloss (out-of-bag)")
plt.show()

# %% [markdown]
# Calculate the score of our hold-out validation dataset

# %%
predictions = model.predict(val_ds)
y_true      = validation_data["label"]

from sklearn.metrics import roc_auc_score
ROC_AUC = roc_auc_score(y_true, predictions)
print("The ROC AUC score is %.5f" % ROC_AUC )
# Out:
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 63ms/step
# The ROC AUC score is 0.99969

# %%
# Compute binary classification metrics with sklearn
import numpy as np
from sklearn.metrics import (
    accuracy_score,
    precision_score,
    recall_score,
    f1_score,
    roc_auc_score,
    average_precision_score,
    confusion_matrix,
    classification_report,
    matthews_corrcoef,
    log_loss,
    brier_score_loss,
)

# Get predictions (probabilities or class labels)
preds = model.predict(test_ds)
# If model outputs probabilities, convert to labels by threshold 0.5
if preds.ndim == 2:
    # For TFDF classification, preds may be class probabilities with shape (N, 2)
    if preds.shape[1] == 2:
        pos_probs = preds[:, 1]
    else:
        # If single-probability column (positive class)
        pos_probs = preds[:, -1]
    y_pred = (pos_probs >= 0.5).astype(int)
else:
    # Already class labels
    y_pred = preds.astype(int)
    pos_probs = None

# Ground truth labels (must be 0/1 integers)
y_true = test_data["label"].astype(int).to_numpy()

# Core metrics
metrics = {}
metrics["accuracy"] = accuracy_score(y_true, y_pred)
metrics["precision"] = precision_score(y_true, y_pred, zero_division=0)
metrics["recall"] = recall_score(y_true, y_pred, zero_division=0)
metrics["f1"] = f1_score(y_true, y_pred, zero_division=0)
metrics["mcc"] = matthews_corrcoef(y_true, y_pred)

# Probabilistic metrics (only if we have probabilities)
if pos_probs is not None:
    metrics["roc_auc"] = roc_auc_score(y_true, pos_probs)
    metrics["pr_auc"] = average_precision_score(y_true, pos_probs)
    metrics["log_loss"] = log_loss(y_true, pos_probs, labels=[0,1])
    metrics["brier_score"] = brier_score_loss(y_true, pos_probs)

# Confusion matrix and detailed report
cm = confusion_matrix(y_true, y_pred, labels=[0,1])
report = classification_report(y_true, y_pred, digits=4)

print("Sklearn binary metrics:")
for k, v in metrics.items():
    print(f"{k}: {v:.4f}")
print("\nConfusion matrix:\n", cm)
print("\nClassification report:\n", report)
# Out:
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 75ms/step
# Sklearn binary metrics:
# accuracy: 0.9894
# precision: 0.8548
# recall: 0.9815
# f1: 0.9138
# mcc: 0.9107
# roc_auc: 0.9978
# pr_auc: 0.9456
# log_loss: 0.0455
# brier_score: 0.0089
#
# Confusion matrix:
#  [[883   9]
#  [  1  53]]
#
# Classification report:
#                precision    recall  f1-score   support
#
#            0     0.9989    0.9899    0.9944       892
#            1     0.8548    0.9815    0.9138        54
#
#     accuracy                         0.9894       946
#    macro avg     0.9269    0.9857    0.9541       946
# weighted avg     0.9906    0.9894    0.9898       946
