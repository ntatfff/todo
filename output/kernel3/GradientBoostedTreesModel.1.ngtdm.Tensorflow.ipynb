# %%
# Import packages and modules
import numpy  as np
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow_decision_forests as tfdf

from sklearn.model_selection import train_test_split
# Out:
# 2026-08-15 04:57:25.968699: I tensorflow/core/util/port.cc:113] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2026-08-15 04:57:26.355958: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2026-08-15 04:57:31.216559: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
# Check the version of TensorFlow Decision Forests
print("Found TensorFlow Decision Forests v" + tfdf.__version__)
# Out:
# Found TensorFlow Decision Forests v1.9.1

# %%
datasetPath = 'dataset/firstorder/kernel5/dataset.csv'

# %%
# Parameters
datasetPath = "dataset/ngtdm/kernel3/1.dataset.csv"

# %%
# train/validation/test = 70/10/20
dataset = pd.read_csv(datasetPath)

train_data, temp_data = train_test_split(dataset, test_size=0.3, random_state=42)
validation_data, test_data = train_test_split(temp_data, test_size=2/3, random_state=42)

# %%
from sklearn.utils.class_weight import compute_class_weight

# tinh class weight tren tap train
classes = np.array([0, 1])
weights = compute_class_weight(class_weight="balanced", classes=classes, y=train_data["label"])
class_weight = {0: weights[0], 1: weights[1]}

# gan sample_weight cho tung dong
train_data["sample_weight"] = train_data["label"].map(class_weight)
validation_data["sample_weight"] = validation_data["label"].map(class_weight)
test_data["sample_weight"] = test_data["label"].map(class_weight)

# Convert the dataset into a TensorFlow dataset.
train_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    train_data, label="label", weight="sample_weight"
)         
val_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    validation_data, label="label", weight="sample_weight"
)
test_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    test_data, label="label", weight="sample_weight"
)
# Out:
# 2026-08-15 04:57:44.943343: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:984] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2026-08-15 04:57:44.944504: W tensorflow/core/common_runtime/gpu/gpu_device.cc:2251] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...

# %%
import keras

# %%
# %%time

# Train a Gradient Boosted Trees model.
model = tfdf.keras.GradientBoostedTreesModel()

# Add evaluation metrics
model.compile(
    metrics=["accuracy"]
)
model.fit(x=train_ds)

# # Train a Gradient Boosted Trees model.
# model = tfdf.keras.GradientBoostedTreesModel(num_trees=1500)
# model.fit(train_ds)
# Out:
# Use /tmp/tmpnmodvyng as temporary training directory
# Reading training dataset...
# [WARNING 26-08-15 04:57:45.0733 UTC gradient_boosted_trees.cc:1840] "goss_alpha" set but "sampling_method" not equal to "GOSS".
# [WARNING 26-08-15 04:57:45.0736 UTC gradient_boosted_trees.cc:1851] "goss_beta" set but "sampling_method" not equal to "GOSS".
# [WARNING 26-08-15 04:57:45.0736 UTC gradient_boosted_trees.cc:1865] "selective_gradient_boosting_ratio" set but "sampling_method" not equal to "SELGB".
# Training dataset read in 0:00:02.598736. Found 3308 examples.
# Training model...
# Model trained in 0:00:00.366652
# Compiling model...
# [INFO 26-08-15 04:57:48.0706 UTC kernel.cc:1233] Loading model from path /tmp/tmpnmodvyng/model/ with prefix 3935d8ddd2f34a85
# [INFO 26-08-15 04:57:48.0750 UTC quick_scorer_extended.cc:911] The binary was compiled without AVX2 support, but your CPU supports it. Enable it for faster model inference.
# [INFO 26-08-15 04:57:48.0753 UTC abstract_model.cc:1362] Engine "GradientBoostedTreesQuickScorerExtended" built
# [INFO 26-08-15 04:57:48.0753 UTC kernel.cc:1061] Use fast generic engine
# Model compiled.
# CPU times: user 5.93 s, sys: 348 ms, total: 6.28 s
# Wall time: 6.25 s

# %%
# Evaluate the model
evaluate = model.evaluate(val_ds, return_dict=True)
print()

for name, value in evaluate.items():
    print(f"{name}: {value:.4f}")
# Out:
# WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 1/1 [==============================] - ETA: 0s - loss: 0.0000e+00 - accuracy: 0.9598
# 1/1 [==============================] - 3s 3s/step - loss: 0.0000e+00 - accuracy: 0.9598
# loss: 0.0000
# accuracy: 0.9598

# %%
# Model Summary
model.summary()
# Out:
# Model: "gradient_boosted_trees_model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
# =================================================================
# Total params: 1 (1.00 Byte)
# Trainable params: 0 (0.00 Byte)
# Non-trainable params: 1 (1.00 Byte)
# _________________________________________________________________
# Type: "GRADIENT_BOOSTED_TREES"
# Task: CLASSIFICATION
# Label: "__LABEL"
#
# Input Features (5):
# 	Busyness
# 	Coarseness
# 	Complexity
# 	Contrast
# 	Strength
#
# Trained with weights
#
# Variable Importance: INV_MEAN_MIN_DEPTH:
#     1.   "Busyness"  0.951415 ################
#     2.   "Strength"  0.277870 #
#     3. "Complexity"  0.225190
#     4.   "Contrast"  0.207538
#     5. "Coarseness"  0.201201
#
# Variable Importance: NUM_AS_ROOT:
#     1.   "Busyness" 65.000000 ################
#     2. "Complexity"  1.000000
#
# Variable Importance: NUM_NODES:
#     1.   "Busyness" 477.000000 ################
#     2.   "Strength" 313.000000 ######
#     3. "Complexity" 243.000000 ##
#     4.   "Contrast" 240.000000 ##
#     5. "Coarseness" 201.000000
#
# Variable Importance: SUM_SCORE:
#     1.   "Busyness" 2963.990042 ################
#     2.   "Strength" 397.130867 #
#     3. "Complexity" 220.766474
#     4.   "Contrast" 185.478756
#     5. "Coarseness" 164.353523
#
#
#
# Loss: BINOMIAL_LOG_LIKELIHOOD
# Validation loss value: 0.267125
# Number of trees per iteration: 1
# Node format: NOT_SET
# Number of trees: 66
# Total number of nodes: 3014
#
# Number of nodes by tree:
# Count: 66 Average: 45.6667 StdDev: 8.91939
# Min: 29 Max: 61 Ignored: 0
# ----------------------------------------------
# [ 29, 30) 2   3.03%   3.03% ###
# [ 30, 32) 2   3.03%   6.06% ###
# [ 32, 33) 0   0.00%   6.06%
# [ 33, 35) 2   3.03%   9.09% ###
# [ 35, 37) 8  12.12%  21.21% ##########
# [ 37, 38) 3   4.55%  25.76% ####
# [ 38, 40) 3   4.55%  30.30% ####
# [ 40, 42) 4   6.06%  36.36% #####
# [ 42, 43) 0   0.00%  36.36%
# [ 43, 45) 6   9.09%  45.45% ########
# [ 45, 47) 2   3.03%  48.48% ###
# [ 47, 48) 5   7.58%  56.06% ######
# [ 48, 50) 4   6.06%  62.12% #####
# [ 50, 52) 8  12.12%  74.24% ##########
# [ 52, 53) 0   0.00%  74.24%
# [ 53, 55) 2   3.03%  77.27% ###
# [ 55, 57) 3   4.55%  81.82% ####
# [ 57, 58) 6   9.09%  90.91% ########
# [ 58, 60) 5   7.58%  98.48% ######
# [ 60, 61] 1   1.52% 100.00% #
#
# Depth by leafs:
# Count: 1540 Average: 4.73831 StdDev: 0.612393
# Min: 2 Max: 5 Ignored: 0
# ----------------------------------------------
# [ 2, 3)   29   1.88%   1.88%
# [ 3, 4)   53   3.44%   5.32%
# [ 4, 5)  210  13.64%  18.96% ##
# [ 5, 5] 1248  81.04% 100.00% ##########
#
# Number of training obs by leaf:
# Count: 1540 Average: 128.186 StdDev: 335.314
# Min: 5 Max: 2771 Ignored: 0
# ----------------------------------------------
# [    5,  143) 1318  85.58%  85.58% ##########
# [  143,  281)   52   3.38%  88.96%
# [  281,  420)   41   2.66%  91.62%
# [  420,  558)   26   1.69%  93.31%
# [  558,  696)   23   1.49%  94.81%
# [  696,  835)    5   0.32%  95.13%
# [  835,  973)   10   0.65%  95.78%
# [  973, 1111)    7   0.45%  96.23%
# [ 1111, 1250)    8   0.52%  96.75%
# [ 1250, 1388)   12   0.78%  97.53%
# [ 1388, 1526)    7   0.45%  97.99%
# [ 1526, 1665)   10   0.65%  98.64%
# [ 1665, 1803)    2   0.13%  98.77%
# [ 1803, 1941)   13   0.84%  99.61%
# [ 1941, 2080)    1   0.06%  99.68%
# [ 2080, 2218)    2   0.13%  99.81%
# [ 2218, 2356)    0   0.00%  99.81%
# [ 2356, 2495)    2   0.13%  99.94%
# [ 2495, 2633)    0   0.00%  99.94%
# [ 2633, 2771]    1   0.06% 100.00%
#
# Attribute in nodes:
# 	477 : Busyness [NUMERICAL]
# 	313 : Strength [NUMERICAL]
# 	243 : Complexity [NUMERICAL]
# 	240 : Contrast [NUMERICAL]
# 	201 : Coarseness [NUMERICAL]
#
# Attribute in nodes with depth <= 0:
# 	65 : Busyness [NUMERICAL]
# 	1 : Complexity [NUMERICAL]
#
# Attribute in nodes with depth <= 1:
# 	132 : Busyness [NUMERICAL]
# 	42 : Strength [NUMERICAL]
# 	12 : Complexity [NUMERICAL]
# 	8 : Coarseness [NUMERICAL]
# 	4 : Contrast [NUMERICAL]
#
# Attribute in nodes with depth <= 2:
# 	201 : Busyness [NUMERICAL]
# 	95 : Strength [NUMERICAL]
# 	67 : Complexity [NUMERICAL]
# 	40 : Contrast [NUMERICAL]
# 	30 : Coarseness [NUMERICAL]
#
# Attribute in nodes with depth <= 3:
# 	310 : Busyness [NUMERICAL]
# 	168 : Strength [NUMERICAL]
# 	149 : Complexity [NUMERICAL]
# 	120 : Contrast [NUMERICAL]
# 	103 : Coarseness [NUMERICAL]
#
# Attribute in nodes with depth <= 5:
# 	477 : Busyness [NUMERICAL]
# 	313 : Strength [NUMERICAL]
# 	243 : Complexity [NUMERICAL]
# 	240 : Contrast [NUMERICAL]
# 	201 : Coarseness [NUMERICAL]
#
# Condition type in nodes:
# 	1474 : HigherCondition
# Condition type in nodes with depth <= 0:
# 	66 : HigherCondition
# Condition type in nodes with depth <= 1:
# 	198 : HigherCondition
# Condition type in nodes with depth <= 2:
# 	433 : HigherCondition
# Condition type in nodes with depth <= 3:
# 	850 : HigherCondition
# Condition type in nodes with depth <= 5:
# 	1474 : HigherCondition
#
# Training logs:
# Number of iteration to final model: 66
# 	Iter:1 train-loss:1.223063 valid-loss:1.243925  train-accuracy:0.959127 valid-accuracy:0.906074
# 	Iter:2 train-loss:1.091174 valid-loss:1.136554  train-accuracy:0.965556 valid-accuracy:0.862406
# 	Iter:3 train-loss:0.982492 valid-loss:1.032817  train-accuracy:0.960734 valid-accuracy:0.928769
# 	Iter:4 train-loss:0.885791 valid-loss:0.957688  train-accuracy:0.965020 valid-accuracy:0.879933
# 	Iter:5 train-loss:0.804833 valid-loss:0.892533  train-accuracy:0.965020 valid-accuracy:0.904351
# 	Iter:6 train-loss:0.736252 valid-loss:0.839209  train-accuracy:0.964663 valid-accuracy:0.904351
# 	Iter:16 train-loss:0.331579 valid-loss:0.446336  train-accuracy:0.979074 valid-accuracy:0.960078
# 	Iter:26 train-loss:0.189025 valid-loss:0.325055  train-accuracy:0.986249 valid-accuracy:0.960078
# 	Iter:36 train-loss:0.129363 valid-loss:0.278811  train-accuracy:0.988928 valid-accuracy:0.958355
# 	Iter:46 train-loss:0.098622 valid-loss:0.280947  train-accuracy:0.991785 valid-accuracy:0.958355
# 	Iter:56 train-loss:0.077243 valid-loss:0.279817  train-accuracy:0.995178 valid-accuracy:0.960078
# 	Iter:66 train-loss:0.061528 valid-loss:0.267125  train-accuracy:0.996607 valid-accuracy:0.963523
# 	Iter:76 train-loss:0.050496 valid-loss:0.287063  train-accuracy:0.997321 valid-accuracy:0.963523
# 	Iter:86 train-loss:0.042045 valid-loss:0.281637  train-accuracy:0.997857 valid-accuracy:0.965246
# 	Iter:96 train-loss:0.035183 valid-loss:0.275768  train-accuracy:0.998571 valid-accuracy:0.966969

# %%
# Model features
model.make_inspector().features()
# Out:
# ["Busyness" (1; #0),
#  "Coarseness" (1; #1),
#  "Complexity" (1; #2),
#  "Contrast" (1; #3),
#  "Strength" (1; #4)]

# %%
# Feature importance
model.make_inspector().variable_importances()
# Out:
# {'INV_MEAN_MIN_DEPTH': [("Busyness" (1; #0), 0.9514148424986651),
#   ("Strength" (1; #4), 0.27787036407870247),
#   ("Complexity" (1; #2), 0.22518993434172738),
#   ("Contrast" (1; #3), 0.20753784662284244),
#   ("Coarseness" (1; #1), 0.201200648190069)],
#  'NUM_AS_ROOT': [("Busyness" (1; #0), 65.0), ("Complexity" (1; #2), 1.0)],
#  'SUM_SCORE': [("Busyness" (1; #0), 2963.9900417532936),
#   ("Strength" (1; #4), 397.13086743588747),
#   ("Complexity" (1; #2), 220.76647442621444),
#   ("Contrast" (1; #3), 185.4787558963877),
#   ("Coarseness" (1; #1), 164.3535234156013)],
#  'NUM_NODES': [("Busyness" (1; #0), 477.0),
#   ("Strength" (1; #4), 313.0),
#   ("Complexity" (1; #2), 243.0),
#   ("Contrast" (1; #3), 240.0),
#   ("Coarseness" (1; #1), 201.0)]}

# %%
# Model self evaluation
model.make_inspector().evaluation()
# Out:
# Evaluation(num_examples=None, accuracy=0.9635231494903564, loss=0.2671247124671936, rmse=None, ndcg=None, aucs=None, auuc=None, qini=None)

# %%
logs = model.make_inspector().training_logs()

plt.figure(figsize=(12, 4))
plt.subplot(1, 2, 1)
plt.plot([log.num_trees for log in logs], [log.evaluation.accuracy for log in logs])
plt.xlabel("Number of trees")
plt.ylabel("Accuracy (out-of-bag)")
plt.subplot(1, 2, 2)
plt.plot([log.num_trees for log in logs], [log.evaluation.loss for log in logs])
plt.xlabel("Number of trees")
plt.ylabel("Logloss (out-of-bag)")
plt.show()

# %% [markdown]
# Calculate the score of our hold-out validation dataset

# %%
predictions = model.predict(val_ds)
y_true      = validation_data["label"]

from sklearn.metrics import roc_auc_score
ROC_AUC = roc_auc_score(y_true, predictions)
print("The ROC AUC score is %.5f" % ROC_AUC )
# Out:
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 52ms/step
# The ROC AUC score is 0.98686

# %%
# Compute binary classification metrics with sklearn
import numpy as np
from sklearn.metrics import (
    accuracy_score,
    precision_score,
    recall_score,
    f1_score,
    roc_auc_score,
    average_precision_score,
    confusion_matrix,
    classification_report,
    matthews_corrcoef,
    log_loss,
    brier_score_loss,
)

# Get predictions (probabilities or class labels)
preds = model.predict(test_ds)
# If model outputs probabilities, convert to labels by threshold 0.5
if preds.ndim == 2:
    # For TFDF classification, preds may be class probabilities with shape (N, 2)
    if preds.shape[1] == 2:
        pos_probs = preds[:, 1]
    else:
        # If single-probability column (positive class)
        pos_probs = preds[:, -1]
    y_pred = (pos_probs >= 0.5).astype(int)
else:
    # Already class labels
    y_pred = preds.astype(int)
    pos_probs = None

# Ground truth labels (must be 0/1 integers)
y_true = test_data["label"].astype(int).to_numpy()

# Core metrics
metrics = {}
metrics["accuracy"] = accuracy_score(y_true, y_pred)
metrics["precision"] = precision_score(y_true, y_pred, zero_division=0)
metrics["recall"] = recall_score(y_true, y_pred, zero_division=0)
metrics["f1"] = f1_score(y_true, y_pred, zero_division=0)
metrics["mcc"] = matthews_corrcoef(y_true, y_pred)

# Probabilistic metrics (only if we have probabilities)
if pos_probs is not None:
    metrics["roc_auc"] = roc_auc_score(y_true, pos_probs)
    metrics["pr_auc"] = average_precision_score(y_true, pos_probs)
    metrics["log_loss"] = log_loss(y_true, pos_probs, labels=[0,1])
    metrics["brier_score"] = brier_score_loss(y_true, pos_probs)

# Confusion matrix and detailed report
cm = confusion_matrix(y_true, y_pred, labels=[0,1])
report = classification_report(y_true, y_pred, digits=4)

print("Sklearn binary metrics:")
for k, v in metrics.items():
    print(f"{k}: {v:.4f}")
print("\nConfusion matrix:\n", cm)
print("\nClassification report:\n", report)
# Out:
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 56ms/step
# Sklearn binary metrics:
# accuracy: 0.9757
# precision: 0.6957
# recall: 0.7805
# f1: 0.7356
# mcc: 0.7242
# roc_auc: 0.9866
# pr_auc: 0.8512
# log_loss: 0.0685
# brier_score: 0.0192
#
# Confusion matrix:
#  [[891  14]
#  [  9  32]]
#
# Classification report:
#                precision    recall  f1-score   support
#
#            0     0.9900    0.9845    0.9873       905
#            1     0.6957    0.7805    0.7356        41
#
#     accuracy                         0.9757       946
#    macro avg     0.8428    0.8825    0.8614       946
# weighted avg     0.9772    0.9757    0.9764       946
