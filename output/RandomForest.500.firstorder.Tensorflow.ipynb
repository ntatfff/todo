# %%
# Import packages and modules
import numpy  as np
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow_decision_forests as tfdf

from sklearn.model_selection import train_test_split
# Out:
# 2026-07-04 07:46:56.166102: I tensorflow/core/util/port.cc:113] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2026-07-04 07:46:56.211010: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2026-07-04 07:47:00.504205: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
# Check the version of TensorFlow Decision Forests
print("Found TensorFlow Decision Forests v" + tfdf.__version__)
# Out:
# Found TensorFlow Decision Forests v1.9.1

# %%
datasetPath = 'dataset/firstorder/kernel5-radius5/dataset.csv'

# %%
# Parameters
datasetPath = "dataset/firstorder/kernel5-radius5/500.dataset.csv"

# %%
# train/validation/test = 70/10/20
dataset = pd.read_csv(datasetPath)

train_data, temp_data = train_test_split(dataset, test_size=0.3, random_state=42)
validation_data, test_data = train_test_split(temp_data, test_size=2/3, random_state=42)

# %%
from sklearn.utils.class_weight import compute_class_weight

# tinh class weight tren tap train
classes = np.array([0, 1])
weights = compute_class_weight(class_weight="balanced", classes=classes, y=train_data["label"])
class_weight = {0: weights[0], 1: weights[1]}

# gan sample_weight cho tung dong
train_data["sample_weight"] = train_data["label"].map(class_weight)
validation_data["sample_weight"] = validation_data["label"].map(class_weight)
test_data["sample_weight"] = test_data["label"].map(class_weight)

# Convert the dataset into a TensorFlow dataset.
train_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    train_data, label="label", weight="sample_weight"
)         
val_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    validation_data, label="label", weight="sample_weight"
)
test_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    test_data, label="label", weight="sample_weight"
)
# Out:
# 2026-07-04 07:47:14.842604: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:984] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2026-07-04 07:47:14.843681: W tensorflow/core/common_runtime/gpu/gpu_device.cc:2251] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...

# %%
import keras

# %%
# %%time

# Train a Random Forest model.
model = tfdf.keras.RandomForestModel()

# Add evaluation metrics
model.compile(
    metrics=["accuracy"]
)
model.fit(x=train_ds)

# # Train a Gradient Boosted Trees model.
# model = tfdf.keras.GradientBoostedTreesModel(num_trees=1500)
# model.fit(train_ds)
# Out:
# Use /tmp/tmpyg6uiqh3 as temporary training directory
# Reading training dataset...
# Training dataset read in 0:00:04.248505. Found 395895 examples.
# Training model...
# [INFO 26-07-04 07:48:12.5586 UTC kernel.cc:1233] Loading model from path /tmp/tmpyg6uiqh3/model/ with prefix f9d4c130bb564c0c
# [INFO 26-07-04 07:48:15.7857 UTC decision_forest.cc:734] Model loaded with 300 root(s), 1959366 node(s), and 18 input feature(s).
# [INFO 26-07-04 07:48:15.7858 UTC abstract_model.cc:1362] Engine "RandomForestOptPred" built
# [INFO 26-07-04 07:48:15.7858 UTC kernel.cc:1061] Use fast generic engine
# Model trained in 0:00:56.817226
# Compiling model...
# Model compiled.
# CPU times: user 10min 11s, sys: 3.55 s, total: 10min 15s
# Wall time: 1min 4s

# %%
# Evaluate the model
evaluate = model.evaluate(val_ds, return_dict=True)
print()

for name, value in evaluate.items():
    print(f"{name}: {value:.4f}")
# Out:
# WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
#  1/57 [..............................] - ETA: 2:51 - loss: 0.0000e+00 - accuracy: 0.9000
#  3/57 [>.............................] - ETA: 1s - loss: 0.0000e+00 - accuracy: 0.8913
#  5/57 [=>............................] - ETA: 1s - loss: 0.0000e+00 - accuracy: 0.8956
#  7/57 [==>...........................] - ETA: 1s - loss: 0.0000e+00 - accuracy: 0.8933
#  9/57 [===>..........................] - ETA: 1s - loss: 0.0000e+00 - accuracy: 0.8924
# 11/57 [====>.........................] - ETA: 1s - loss: 0.0000e+00 - accuracy: 0.8923
# 13/57 [=====>........................] - ETA: 1s - loss: 0.0000e+00 - accuracy: 0.8924
# 15/57 [======>.......................] - ETA: 1s - loss: 0.0000e+00 - accuracy: 0.8915
# 17/57 [=======>......................] - ETA: 1s - loss: 0.0000e+00 - accuracy: 0.8916
# 19/57 [=========>....................] - ETA: 1s - loss: 0.0000e+00 - accuracy: 0.8916
# 21/57 [==========>...................] - ETA: 1s - loss: 0.0000e+00 - accuracy: 0.8913
# 23/57 [===========>..................] - ETA: 1s - loss: 0.0000e+00 - accuracy: 0.8907
# 25/57 [============>.................] - ETA: 1s - loss: 0.0000e+00 - accuracy: 0.8912
# 27/57 [=============>................] - ETA: 1s - loss: 0.0000e+00 - accuracy: 0.8917
# 29/57 [==============>...............] - ETA: 1s - loss: 0.0000e+00 - accuracy: 0.8924
# 31/57 [===============>..............] - ETA: 0s - loss: 0.0000e+00 - accuracy: 0.8919
# 33/57 [================>.............] - ETA: 0s - loss: 0.0000e+00 - accuracy: 0.8916
# 35/57 [=================>............] - ETA: 0s - loss: 0.0000e+00 - accuracy: 0.8912
# 37/57 [==================>...........] - ETA: 0s - loss: 0.0000e+00 - accuracy: 0.8914
# 39/57 [===================>..........] - ETA: 0s - loss: 0.0000e+00 - accuracy: 0.8920
# 41/57 [====================>.........] - ETA: 0s - loss: 0.0000e+00 - accuracy: 0.8915
# 43/57 [=====================>........] - ETA: 0s - loss: 0.0000e+00 - accuracy: 0.8915
# 45/57 [======================>.......] - ETA: 0s - loss: 0.0000e+00 - accuracy: 0.8911
# 47/57 [=======================>......] - ETA: 0s - loss: 0.0000e+00 - accuracy: 0.8915
# 48/57 [========================>.....] - ETA: 0s - loss: 0.0000e+00 - accuracy: 0.8917
# 50/57 [=========================>....] - ETA: 0s - loss: 0.0000e+00 - accuracy: 0.8915
# 52/57 [==========================>...] - ETA: 0s - loss: 0.0000e+00 - accuracy: 0.8921
# 54/57 [===========================>..] - ETA: 0s - loss: 0.0000e+00 - accuracy: 0.8924
# 56/57 [============================>.] - ETA: 0s - loss: 0.0000e+00 - accuracy: 0.8924
# 57/57 [==============================] - 5s 39ms/step - loss: 0.0000e+00 - accuracy: 0.8923
# loss: 0.0000
# accuracy: 0.8923

# %%
# Model Summary
model.summary()
# Out:
# Model: "random_forest_model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
# =================================================================
# Total params: 1 (1.00 Byte)
# Trainable params: 0 (0.00 Byte)
# Non-trainable params: 1 (1.00 Byte)
# _________________________________________________________________
# Type: "RANDOM_FOREST"
# Task: CLASSIFICATION
# Label: "__LABEL"
#
# Input Features (18):
# 	10Percentile
# 	90Percentile
# 	Energy
# 	Entropy
# 	InterquartileRange
# 	Kurtosis
# 	Maximum
# 	Mean
# 	MeanAbsoluteDeviation
# 	Median
# 	Minimum
# 	Range
# 	RobustMeanAbsoluteDeviation
# 	RootMeanSquared
# 	Skewness
# 	TotalEnergy
# 	Uniformity
# 	Variance
#
# Trained with weights
#
# Variable Importance: INV_MEAN_MIN_DEPTH:
#     1.                        "Mean"  0.181000 ################
#     2.                     "Minimum"  0.122849 #######
#     3.                 "TotalEnergy"  0.120137 ######
#     4.             "RootMeanSquared"  0.115253 #####
#     5.                      "Median"  0.114368 #####
#     6.                      "Energy"  0.113512 #####
#     7.                     "Maximum"  0.111103 #####
#     8.                       "Range"  0.107318 ####
#     9.                "90Percentile"  0.106640 ####
#    10.                "10Percentile"  0.093329 ##
#    11.                    "Kurtosis"  0.092836 ##
#    12.                    "Skewness"  0.088756 #
#    13.          "InterquartileRange"  0.087148 #
#    14. "RobustMeanAbsoluteDeviation"  0.086336 #
#    15.                  "Uniformity"  0.082261
#    16.       "MeanAbsoluteDeviation"  0.081280
#    17.                    "Variance"  0.079988
#    18.                     "Entropy"  0.077077
#
# Variable Importance: NUM_AS_ROOT:
#     1.            "Mean" 93.000000 ################
#     2.          "Median" 61.000000 ##########
#     3.     "TotalEnergy" 46.000000 #######
#     4. "RootMeanSquared" 39.000000 ######
#     5.          "Energy" 25.000000 ####
#     6.    "10Percentile" 16.000000 ##
#     7.    "90Percentile" 11.000000 #
#     8.         "Minimum"  6.000000
#     9.         "Entropy"  1.000000
#    10.         "Maximum"  1.000000
#    11.      "Uniformity"  1.000000
#
# Variable Importance: NUM_NODES:
#     1.                    "Skewness" 73516.000000 ################
#     2.                     "Maximum" 71579.000000 ###############
#     3.                       "Range" 67251.000000 #############
#     4.                    "Kurtosis" 63625.000000 ###########
#     5.                      "Median" 59477.000000 #########
#     6.                  "Uniformity" 58174.000000 #########
#     7.                "90Percentile" 56378.000000 ########
#     8.                     "Entropy" 55232.000000 #######
#     9.                     "Minimum" 54241.000000 #######
#    10.                    "Variance" 54105.000000 #######
#    11. "RobustMeanAbsoluteDeviation" 52697.000000 ######
#    12.          "InterquartileRange" 52489.000000 ######
#    13.                "10Percentile" 50917.000000 #####
#    14.       "MeanAbsoluteDeviation" 50235.000000 #####
#    15.                        "Mean" 45382.000000 ###
#    16.                 "TotalEnergy" 38224.000000
#    17.             "RootMeanSquared" 38057.000000
#    18.                      "Energy" 37954.000000
#
# Variable Importance: SUM_SCORE:
#     1.                        "Mean" 7705492.281481 ################
#     2.                 "TotalEnergy" 4501678.037782 ########
#     3.                      "Median" 4389179.663851 #######
#     4.             "RootMeanSquared" 4030394.413592 ######
#     5.                      "Energy" 3709873.527833 ######
#     6.                     "Maximum" 3673627.476051 #####
#     7.                     "Minimum" 3505351.754041 #####
#     8.                "90Percentile" 3482513.723336 #####
#     9.                       "Range" 3168181.337732 ####
#    10.                "10Percentile" 2597275.644286 ###
#    11.                    "Skewness" 2334688.494287 ##
#    12.                    "Kurtosis" 2308398.229140 ##
#    13. "RobustMeanAbsoluteDeviation" 1868378.613334 #
#    14.          "InterquartileRange" 1786602.607665 #
#    15.                  "Uniformity" 1563874.456216
#    16.       "MeanAbsoluteDeviation" 1547909.015855
#    17.                    "Variance" 1513024.319537
#    18.                     "Entropy" 1262025.683178
#
#
#
# Winner takes all: true
# Out-of-bag evaluation: accuracy:0.82289 logloss:0.626385
# Number of trees: 300
# Total number of nodes: 1959366
#
# Number of nodes by tree:
# Count: 300 Average: 6531.22 StdDev: 308.135
# Min: 5603 Max: 7613 Ignored: 0
# ----------------------------------------------
# [ 5603, 5703)  3   1.00%   1.00% #
# [ 5703, 5804)  0   0.00%   1.00%
# [ 5804, 5904)  3   1.00%   2.00% #
# [ 5904, 6005)  2   0.67%   2.67%
# [ 6005, 6105) 12   4.00%   6.67% ##
# [ 6105, 6206) 12   4.00%  10.67% ##
# [ 6206, 6306) 24   8.00%  18.67% #####
# [ 6306, 6407) 52  17.33%  36.00% ##########
# [ 6407, 6507) 39  13.00%  49.00% ########
# [ 6507, 6608) 47  15.67%  64.67% #########
# [ 6608, 6709) 35  11.67%  76.33% #######
# [ 6709, 6809) 28   9.33%  85.67% #####
# [ 6809, 6910) 14   4.67%  90.33% ###
# [ 6910, 7010) 10   3.33%  93.67% ##
# [ 7010, 7111)  6   2.00%  95.67% #
# [ 7111, 7211)  3   1.00%  96.67% #
# [ 7211, 7312)  3   1.00%  97.67% #
# [ 7312, 7412)  2   0.67%  98.33%
# [ 7412, 7513)  2   0.67%  99.00%
# [ 7513, 7613]  3   1.00% 100.00% #
#
# Depth by leafs:
# Count: 979833 Average: 13.4939 StdDev: 1.83207
# Min: 3 Max: 15 Ignored: 0
# ----------------------------------------------
# [  3,  4)      2   0.00%   0.00%
# [  4,  5)     39   0.00%   0.00%
# [  5,  6)    475   0.05%   0.05%
# [  6,  7)   1481   0.15%   0.20%
# [  7,  8)   4550   0.46%   0.67%
# [  8,  9)  10902   1.11%   1.78%
# [  9, 10)  22796   2.33%   4.11% #
# [ 10, 11)  40874   4.17%   8.28% #
# [ 11, 12)  67141   6.85%  15.13% ##
# [ 12, 13)  98859  10.09%  25.22% ##
# [ 13, 14) 134442  13.72%  38.94% ###
# [ 14, 15) 169328  17.28%  56.22% ####
# [ 15, 15] 428944  43.78% 100.00% ##########
#
# Number of training obs by leaf:
# Count: 979833 Average: 121.213 StdDev: 489.571
# Min: 5 Max: 23447 Ignored: 0
# ----------------------------------------------
# [     5,  1177) 962248  98.21%  98.21% ##########
# [  1177,  2349)  10534   1.08%  99.28%
# [  2349,  3521)   3153   0.32%  99.60%
# [  3521,  4693)   1474   0.15%  99.75%
# [  4693,  5865)    863   0.09%  99.84%
# [  5865,  7037)    560   0.06%  99.90%
# [  7037,  8210)    387   0.04%  99.94%
# [  8210,  9382)    227   0.02%  99.96%
# [  9382, 10554)    155   0.02%  99.98%
# [ 10554, 11726)     81   0.01%  99.98%
# [ 11726, 12898)     50   0.01%  99.99%
# [ 12898, 14070)     30   0.00%  99.99%
# [ 14070, 15242)     27   0.00% 100.00%
# [ 15242, 16415)     18   0.00% 100.00%
# [ 16415, 17587)     12   0.00% 100.00%
# [ 17587, 18759)      5   0.00% 100.00%
# [ 18759, 19931)      2   0.00% 100.00%
# [ 19931, 21103)      5   0.00% 100.00%
# [ 21103, 22275)      0   0.00% 100.00%
# [ 22275, 23447]      2   0.00% 100.00%
#
# Attribute in nodes:
# 	73516 : Skewness [NUMERICAL]
# 	71579 : Maximum [NUMERICAL]
# 	67251 : Range [NUMERICAL]
# 	63625 : Kurtosis [NUMERICAL]
# 	59477 : Median [NUMERICAL]
# 	58174 : Uniformity [NUMERICAL]
# 	56378 : 90Percentile [NUMERICAL]
# 	55232 : Entropy [NUMERICAL]
# 	54241 : Minimum [NUMERICAL]
# 	54105 : Variance [NUMERICAL]
# 	52697 : RobustMeanAbsoluteDeviation [NUMERICAL]
# 	52489 : InterquartileRange [NUMERICAL]
# 	50917 : 10Percentile [NUMERICAL]
# 	50235 : MeanAbsoluteDeviation [NUMERICAL]
# 	45382 : Mean [NUMERICAL]
# 	38224 : TotalEnergy [NUMERICAL]
# 	38057 : RootMeanSquared [NUMERICAL]
# 	37954 : Energy [NUMERICAL]
#
# Attribute in nodes with depth <= 0:
# 	93 : Mean [NUMERICAL]
# 	61 : Median [NUMERICAL]
# 	46 : TotalEnergy [NUMERICAL]
# 	39 : RootMeanSquared [NUMERICAL]
# 	25 : Energy [NUMERICAL]
# 	16 : 10Percentile [NUMERICAL]
# 	11 : 90Percentile [NUMERICAL]
# 	6 : Minimum [NUMERICAL]
# 	1 : Uniformity [NUMERICAL]
# 	1 : Maximum [NUMERICAL]
# 	1 : Entropy [NUMERICAL]
#
# Attribute in nodes with depth <= 1:
# 	299 : Mean [NUMERICAL]
# 	158 : TotalEnergy [NUMERICAL]
# 	126 : Energy [NUMERICAL]
# 	116 : RootMeanSquared [NUMERICAL]
# 	99 : Median [NUMERICAL]
# 	36 : 90Percentile [NUMERICAL]
# 	27 : 10Percentile [NUMERICAL]
# 	26 : Minimum [NUMERICAL]
# 	7 : Uniformity [NUMERICAL]
# 	3 : Maximum [NUMERICAL]
# 	2 : Entropy [NUMERICAL]
# 	1 : Kurtosis [NUMERICAL]
#
# Attribute in nodes with depth <= 2:
# 	415 : Mean [NUMERICAL]
# 	229 : TotalEnergy [NUMERICAL]
# 	214 : Energy [NUMERICAL]
# 	200 : RootMeanSquared [NUMERICAL]
# 	184 : Minimum [NUMERICAL]
# 	177 : Range [NUMERICAL]
# 	141 : Maximum [NUMERICAL]
# 	138 : Median [NUMERICAL]
# 	107 : 90Percentile [NUMERICAL]
# 	88 : Kurtosis [NUMERICAL]
# 	79 : 10Percentile [NUMERICAL]
# 	40 : InterquartileRange [NUMERICAL]
# 	31 : RobustMeanAbsoluteDeviation [NUMERICAL]
# 	21 : Uniformity [NUMERICAL]
# 	18 : MeanAbsoluteDeviation [NUMERICAL]
# 	13 : Variance [NUMERICAL]
# 	3 : Entropy [NUMERICAL]
# 	2 : Skewness [NUMERICAL]
#
# Attribute in nodes with depth <= 3:
# 	624 : Mean [NUMERICAL]
# 	420 : Minimum [NUMERICAL]
# 	407 : TotalEnergy [NUMERICAL]
# 	385 : RootMeanSquared [NUMERICAL]
# 	385 : Energy [NUMERICAL]
# 	360 : Range [NUMERICAL]
# 	346 : 90Percentile [NUMERICAL]
# 	328 : Maximum [NUMERICAL]
# 	254 : Kurtosis [NUMERICAL]
# 	253 : Median [NUMERICAL]
# 	162 : 10Percentile [NUMERICAL]
# 	158 : InterquartileRange [NUMERICAL]
# 	144 : RobustMeanAbsoluteDeviation [NUMERICAL]
# 	85 : Uniformity [NUMERICAL]
# 	71 : MeanAbsoluteDeviation [NUMERICAL]
# 	47 : Variance [NUMERICAL]
# 	41 : Skewness [NUMERICAL]
# 	28 : Entropy [NUMERICAL]
#
# Attribute in nodes with depth <= 5:
# 	1604 : Minimum [NUMERICAL]
# 	1454 : Mean [NUMERICAL]
# 	1440 : Range [NUMERICAL]
# 	1406 : Kurtosis [NUMERICAL]
# 	1315 : Maximum [NUMERICAL]
# 	1188 : 90Percentile [NUMERICAL]
# 	1106 : Median [NUMERICAL]
# 	1009 : TotalEnergy [NUMERICAL]
# 	999 : Energy [NUMERICAL]
# 	989 : RootMeanSquared [NUMERICAL]
# 	989 : InterquartileRange [NUMERICAL]
# 	975 : RobustMeanAbsoluteDeviation [NUMERICAL]
# 	855 : 10Percentile [NUMERICAL]
# 	780 : Skewness [NUMERICAL]
# 	656 : MeanAbsoluteDeviation [NUMERICAL]
# 	637 : Uniformity [NUMERICAL]
# 	482 : Variance [NUMERICAL]
# 	410 : Entropy [NUMERICAL]
#
# Condition type in nodes:
# 	979533 : HigherCondition
# Condition type in nodes with depth <= 0:
# 	300 : HigherCondition
# Condition type in nodes with depth <= 1:
# 	900 : HigherCondition
# Condition type in nodes with depth <= 2:
# 	2100 : HigherCondition
# Condition type in nodes with depth <= 3:
# 	4498 : HigherCondition
# Condition type in nodes with depth <= 5:
# 	18294 : HigherCondition
# Node format: NOT_SET
#
# Training OOB:
# 	trees: 1, Out-of-bag evaluation: accuracy:0.789116 logloss:7.60105
# 	trees: 11, Out-of-bag evaluation: accuracy:0.798729 logloss:3.39106
# 	trees: 21, Out-of-bag evaluation: accuracy:0.811519 logloss:2.19227
# 	trees: 31, Out-of-bag evaluation: accuracy:0.815462 logloss:1.72374
# 	trees: 41, Out-of-bag evaluation: accuracy:0.817538 logloss:1.47159
# 	trees: 51, Out-of-bag evaluation: accuracy:0.817728 logloss:1.30968
# 	trees: 61, Out-of-bag evaluation: accuracy:0.818523 logloss:1.1841
# 	trees: 71, Out-of-bag evaluation: accuracy:0.819504 logloss:1.09944
# 	trees: 81, Out-of-bag evaluation: accuracy:0.820567 logloss:1.02317
# 	trees: 91, Out-of-bag evaluation: accuracy:0.820892 logloss:0.963223
# 	trees: 101, Out-of-bag evaluation: accuracy:0.82096 logloss:0.915007
# 	trees: 111, Out-of-bag evaluation: accuracy:0.820662 logloss:0.882451
# 	trees: 121, Out-of-bag evaluation: accuracy:0.821457 logloss:0.856736
# 	trees: 131, Out-of-bag evaluation: accuracy:0.821554 logloss:0.840728
# 	trees: 141, Out-of-bag evaluation: accuracy:0.822015 logloss:0.813859
# 	trees: 151, Out-of-bag evaluation: accuracy:0.822032 logloss:0.784103
# 	trees: 161, Out-of-bag evaluation: accuracy:0.822107 logloss:0.771467
# 	trees: 171, Out-of-bag evaluation: accuracy:0.822321 logloss:0.756585
# 	trees: 181, Out-of-bag evaluation: accuracy:0.822248 logloss:0.746959
# 	trees: 191, Out-of-bag evaluation: accuracy:0.82262 logloss:0.735215
# 	trees: 201, Out-of-bag evaluation: accuracy:0.822573 logloss:0.718907
# 	trees: 211, Out-of-bag evaluation: accuracy:0.822233 logloss:0.707025
# 	trees: 221, Out-of-bag evaluation: accuracy:0.822553 logloss:0.694781
# 	trees: 231, Out-of-bag evaluation: accuracy:0.822714 logloss:0.681577
# 	trees: 241, Out-of-bag evaluation: accuracy:0.822881 logloss:0.669142
# 	trees: 251, Out-of-bag evaluation: accuracy:0.822845 logloss:0.660819
# 	trees: 261, Out-of-bag evaluation: accuracy:0.822758 logloss:0.654504
# 	trees: 271, Out-of-bag evaluation: accuracy:0.822684 logloss:0.647365
# 	trees: 281, Out-of-bag evaluation: accuracy:0.822776 logloss:0.641851
# 	trees: 291, Out-of-bag evaluation: accuracy:0.823225 logloss:0.634561
# 	trees: 300, Out-of-bag evaluation: accuracy:0.82289 logloss:0.626385

# %%
# Model features
model.make_inspector().features()
# Out:
# ["10Percentile" (1; #0),
#  "90Percentile" (1; #1),
#  "Energy" (1; #2),
#  "Entropy" (1; #3),
#  "InterquartileRange" (1; #4),
#  "Kurtosis" (1; #5),
#  "Maximum" (1; #6),
#  "Mean" (1; #7),
#  "MeanAbsoluteDeviation" (1; #8),
#  "Median" (1; #9),
#  "Minimum" (1; #10),
#  "Range" (1; #11),
#  "RobustMeanAbsoluteDeviation" (1; #12),
#  "RootMeanSquared" (1; #13),
#  "Skewness" (1; #14),
#  "TotalEnergy" (1; #15),
#  "Uniformity" (1; #16),
#  "Variance" (1; #17)]

# %%
# Feature importance
model.make_inspector().variable_importances()
# Out:
# {'INV_MEAN_MIN_DEPTH': [("Mean" (1; #7), 0.1810000429073142),
#   ("Minimum" (1; #10), 0.12284865020814859),
#   ("TotalEnergy" (1; #15), 0.12013701968293497),
#   ("RootMeanSquared" (1; #13), 0.11525306390631372),
#   ("Median" (1; #9), 0.11436764487280181),
#   ("Energy" (1; #2), 0.11351221622023733),
#   ("Maximum" (1; #6), 0.11110275519098074),
#   ("Range" (1; #11), 0.10731841869598528),
#   ("90Percentile" (1; #1), 0.10663980233066776),
#   ("10Percentile" (1; #0), 0.09332907192955937),
#   ("Kurtosis" (1; #5), 0.0928360767196514),
#   ("Skewness" (1; #14), 0.08875575888206476),
#   ("InterquartileRange" (1; #4), 0.08714759635916708),
#   ("RobustMeanAbsoluteDeviation" (1; #12), 0.08633579302494589),
#   ("Uniformity" (1; #16), 0.08226104728260196),
#   ("MeanAbsoluteDeviation" (1; #8), 0.08127995435816665),
#   ("Variance" (1; #17), 0.07998781053556507),
#   ("Entropy" (1; #3), 0.07707727688333849)],
#  'NUM_AS_ROOT': [("Mean" (1; #7), 93.0),
#   ("Median" (1; #9), 61.0),
#   ("TotalEnergy" (1; #15), 46.0),
#   ("RootMeanSquared" (1; #13), 39.0),
#   ("Energy" (1; #2), 25.0),
#   ("10Percentile" (1; #0), 16.0),
#   ("90Percentile" (1; #1), 11.0),
#   ("Minimum" (1; #10), 6.0),
#   ("Entropy" (1; #3), 1.0),
#   ("Maximum" (1; #6), 1.0),
#   ("Uniformity" (1; #16), 1.0)],
#  'SUM_SCORE': [("Mean" (1; #7), 7705492.281480747),
#   ("TotalEnergy" (1; #15), 4501678.037782269),
#   ("Median" (1; #9), 4389179.663851446),
#   ("RootMeanSquared" (1; #13), 4030394.413591994),
#   ("Energy" (1; #2), 3709873.5278327647),
#   ("Maximum" (1; #6), 3673627.4760512635),
#   ("Minimum" (1; #10), 3505351.7540408047),
#   ("90Percentile" (1; #1), 3482513.723335902),
#   ("Range" (1; #11), 3168181.3377323705),
#   ("10Percentile" (1; #0), 2597275.6442861534),
#   ("Skewness" (1; #14), 2334688.494286512),
#   ("Kurtosis" (1; #5), 2308398.2291396707),
#   ("RobustMeanAbsoluteDeviation" (1; #12), 1868378.6133335512),
#   ("InterquartileRange" (1; #4), 1786602.6076645032),
#   ("Uniformity" (1; #16), 1563874.4562156096),
#   ("MeanAbsoluteDeviation" (1; #8), 1547909.0158548546),
#   ("Variance" (1; #17), 1513024.3195369798),
#   ("Entropy" (1; #3), 1262025.6831775869)],
#  'NUM_NODES': [("Skewness" (1; #14), 73516.0),
#   ("Maximum" (1; #6), 71579.0),
#   ("Range" (1; #11), 67251.0),
#   ("Kurtosis" (1; #5), 63625.0),
#   ("Median" (1; #9), 59477.0),
#   ("Uniformity" (1; #16), 58174.0),
#   ("90Percentile" (1; #1), 56378.0),
#   ("Entropy" (1; #3), 55232.0),
#   ("Minimum" (1; #10), 54241.0),
#   ("Variance" (1; #17), 54105.0),
#   ("RobustMeanAbsoluteDeviation" (1; #12), 52697.0),
#   ("InterquartileRange" (1; #4), 52489.0),
#   ("10Percentile" (1; #0), 50917.0),
#   ("MeanAbsoluteDeviation" (1; #8), 50235.0),
#   ("Mean" (1; #7), 45382.0),
#   ("TotalEnergy" (1; #15), 38224.0),
#   ("RootMeanSquared" (1; #13), 38057.0),
#   ("Energy" (1; #2), 37954.0)]}

# %%
# Model self evaluation
model.make_inspector().evaluation()
# Out:
# Evaluation(num_examples=395895, accuracy=0.8228903857086953, loss=0.626384899824851, rmse=None, ndcg=None, aucs=None, auuc=None, qini=None)

# %%
logs = model.make_inspector().training_logs()

plt.figure(figsize=(12, 4))
plt.subplot(1, 2, 1)
plt.plot([log.num_trees for log in logs], [log.evaluation.accuracy for log in logs])
plt.xlabel("Number of trees")
plt.ylabel("Accuracy (out-of-bag)")
plt.subplot(1, 2, 2)
plt.plot([log.num_trees for log in logs], [log.evaluation.loss for log in logs])
plt.xlabel("Number of trees")
plt.ylabel("Logloss (out-of-bag)")
plt.show()

# %% [markdown]
# Calculate the score of our hold-out validation dataset

# %%
predictions = model.predict(val_ds)
y_true      = validation_data["label"]

from sklearn.metrics import roc_auc_score
ROC_AUC = roc_auc_score(y_true, predictions)
print("The ROC AUC score is %.5f" % ROC_AUC )
# Out:
#  1/57 [..............................] - ETA: 5s
#  3/57 [>.............................] - ETA: 2s
#  5/57 [=>............................] - ETA: 1s
#  7/57 [==>...........................] - ETA: 1s
#  9/57 [===>..........................] - ETA: 1s
# 11/57 [====>.........................] - ETA: 1s
# 13/57 [=====>........................] - ETA: 1s
# 15/57 [======>.......................] - ETA: 1s
# 17/57 [=======>......................] - ETA: 1s
# 19/57 [=========>....................] - ETA: 1s
# 21/57 [==========>...................] - ETA: 1s
# 23/57 [===========>..................] - ETA: 1s
# 25/57 [============>.................] - ETA: 1s
# 27/57 [=============>................] - ETA: 1s
# 29/57 [==============>...............] - ETA: 1s
# 31/57 [===============>..............] - ETA: 0s
# 33/57 [================>.............] - ETA: 0s
# 35/57 [=================>............] - ETA: 0s
# 37/57 [==================>...........] - ETA: 0s
# 39/57 [===================>..........] - ETA: 0s
# 41/57 [====================>.........] - ETA: 0s
# 43/57 [=====================>........] - ETA: 0s
# 45/57 [======================>.......] - ETA: 0s
# 47/57 [=======================>......] - ETA: 0s
# 49/57 [========================>.....] - ETA: 0s
# 51/57 [=========================>....] - ETA: 0s
# 53/57 [==========================>...] - ETA: 0s
# 55/57 [===========================>..] - ETA: 0s
# 57/57 [==============================] - ETA: 0s
# 57/57 [==============================] - 2s 38ms/step
# The ROC AUC score is 0.91702

# %%
# Compute binary classification metrics with sklearn
import numpy as np
from sklearn.metrics import (
    accuracy_score,
    precision_score,
    recall_score,
    f1_score,
    roc_auc_score,
    average_precision_score,
    confusion_matrix,
    classification_report,
    matthews_corrcoef,
    log_loss,
    brier_score_loss,
)

# Get predictions (probabilities or class labels)
preds = model.predict(test_ds)
# If model outputs probabilities, convert to labels by threshold 0.5
if preds.ndim == 2:
    # For TFDF classification, preds may be class probabilities with shape (N, 2)
    if preds.shape[1] == 2:
        pos_probs = preds[:, 1]
    else:
        # If single-probability column (positive class)
        pos_probs = preds[:, -1]
    y_pred = (pos_probs >= 0.5).astype(int)
else:
    # Already class labels
    y_pred = preds.astype(int)
    pos_probs = None

# Ground truth labels (must be 0/1 integers)
y_true = test_data["label"].astype(int).to_numpy()

# Core metrics
metrics = {}
metrics["accuracy"] = accuracy_score(y_true, y_pred)
metrics["precision"] = precision_score(y_true, y_pred, zero_division=0)
metrics["recall"] = recall_score(y_true, y_pred, zero_division=0)
metrics["f1"] = f1_score(y_true, y_pred, zero_division=0)
metrics["mcc"] = matthews_corrcoef(y_true, y_pred)

# Probabilistic metrics (only if we have probabilities)
if pos_probs is not None:
    metrics["roc_auc"] = roc_auc_score(y_true, pos_probs)
    metrics["pr_auc"] = average_precision_score(y_true, pos_probs)
    metrics["log_loss"] = log_loss(y_true, pos_probs, labels=[0,1])
    metrics["brier_score"] = brier_score_loss(y_true, pos_probs)

# Confusion matrix and detailed report
cm = confusion_matrix(y_true, y_pred, labels=[0,1])
report = classification_report(y_true, y_pred, digits=4)

print("Sklearn binary metrics:")
for k, v in metrics.items():
    print(f"{k}: {v:.4f}")
print("\nConfusion matrix:\n", cm)
print("\nClassification report:\n", report)
# Out:
#   1/114 [..............................] - ETA: 11s
#   3/114 [..............................] - ETA: 5s
#   5/114 [>.............................] - ETA: 4s
#   7/114 [>.............................] - ETA: 4s
#   9/114 [=>............................] - ETA: 4s
#  11/114 [=>............................] - ETA: 4s
#  13/114 [==>...........................] - ETA: 4s
#  15/114 [==>...........................] - ETA: 4s
#  17/114 [===>..........................] - ETA: 3s
#  19/114 [====>.........................] - ETA: 3s
#  21/114 [====>.........................] - ETA: 3s
#  23/114 [=====>........................] - ETA: 3s
#  25/114 [=====>........................] - ETA: 3s
#  27/114 [======>.......................] - ETA: 3s
#  29/114 [======>.......................] - ETA: 3s
#  31/114 [=======>......................] - ETA: 3s
#  33/114 [=======>......................] - ETA: 3s
#  35/114 [========>.....................] - ETA: 3s
#  37/114 [========>.....................] - ETA: 3s
#  39/114 [=========>....................] - ETA: 2s
#  41/114 [=========>....................] - ETA: 2s
#  43/114 [==========>...................] - ETA: 2s
#  45/114 [==========>...................] - ETA: 2s
#  47/114 [===========>..................] - ETA: 2s
#  49/114 [===========>..................] - ETA: 2s
#  51/114 [============>.................] - ETA: 2s
#  53/114 [============>.................] - ETA: 2s
#  55/114 [=============>................] - ETA: 2s
#  57/114 [==============>...............] - ETA: 2s
#  59/114 [==============>...............] - ETA: 2s
#  61/114 [===============>..............] - ETA: 2s
#  63/114 [===============>..............] - ETA: 2s
#  65/114 [================>.............] - ETA: 1s
#  67/114 [================>.............] - ETA: 1s
#  69/114 [=================>............] - ETA: 1s
#  71/114 [=================>............] - ETA: 1s
#  73/114 [==================>...........] - ETA: 1s
#  75/114 [==================>...........] - ETA: 1s
#  77/114 [===================>..........] - ETA: 1s
#  79/114 [===================>..........] - ETA: 1s
#  81/114 [====================>.........] - ETA: 1s
#  83/114 [====================>.........] - ETA: 1s
#  85/114 [=====================>........] - ETA: 1s
#  87/114 [=====================>........] - ETA: 1s
#  89/114 [======================>.......] - ETA: 0s
#  91/114 [======================>.......] - ETA: 0s
#  93/114 [=======================>......] - ETA: 0s
#  95/114 [========================>.....] - ETA: 0s
#  97/114 [========================>.....] - ETA: 0s
#  99/114 [=========================>....] - ETA: 0s
# 101/114 [=========================>....] - ETA: 0s
# 103/114 [==========================>...] - ETA: 0s
# 105/114 [==========================>...] - ETA: 0s
# 107/114 [===========================>..] - ETA: 0s
# 109/114 [===========================>..] - ETA: 0s
# 111/114 [============================>.] - ETA: 0s
# 113/114 [============================>.] - ETA: 0s
# 114/114 [==============================] - 5s 39ms/step
# Sklearn binary metrics:
# accuracy: 0.8914
# precision: 0.3438
# recall: 0.7582
# f1: 0.4730
# mcc: 0.4632
# roc_auc: 0.9184
# pr_auc: 0.5719
# log_loss: 0.2542
# brier_score: 0.0767
#
# Confusion matrix:
#  [[95324 10521]
#  [ 1758  5511]]
#
# Classification report:
#                precision    recall  f1-score   support
#
#            0     0.9819    0.9006    0.9395    105845
#            1     0.3438    0.7582    0.4730      7269
#
#     accuracy                         0.8914    113114
#    macro avg     0.6628    0.8294    0.7063    113114
# weighted avg     0.9409    0.8914    0.9095    113114
