# %%
# Import packages and modules
import numpy  as np
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow_decision_forests as tfdf

from sklearn.model_selection import train_test_split
# Out:
# 2026-07-04 09:17:33.741113: I tensorflow/core/util/port.cc:113] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2026-07-04 09:17:33.789112: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2026-07-04 09:17:38.042760: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
# Check the version of TensorFlow Decision Forests
print("Found TensorFlow Decision Forests v" + tfdf.__version__)
# Out:
# Found TensorFlow Decision Forests v1.9.1

# %%
datasetPath = 'dataset/firstorder/kernel5-radius5/dataset.csv'

# %%
# Parameters
datasetPath = "dataset/ngtdm/kernel5-radius5/500.dataset.csv"

# %%
# train/validation/test = 70/10/20
dataset = pd.read_csv(datasetPath)

train_data, temp_data = train_test_split(dataset, test_size=0.3, random_state=42)
validation_data, test_data = train_test_split(temp_data, test_size=2/3, random_state=42)

# %%
from sklearn.utils.class_weight import compute_class_weight

# tinh class weight tren tap train
classes = np.array([0, 1])
weights = compute_class_weight(class_weight="balanced", classes=classes, y=train_data["label"])
class_weight = {0: weights[0], 1: weights[1]}

# gan sample_weight cho tung dong
train_data["sample_weight"] = train_data["label"].map(class_weight)
validation_data["sample_weight"] = validation_data["label"].map(class_weight)
test_data["sample_weight"] = test_data["label"].map(class_weight)

# Convert the dataset into a TensorFlow dataset.
train_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    train_data, label="label", weight="sample_weight"
)         
val_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    validation_data, label="label", weight="sample_weight"
)
test_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    test_data, label="label", weight="sample_weight"
)
# Out:
# 2026-07-04 09:17:50.063441: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:984] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2026-07-04 09:17:50.064966: W tensorflow/core/common_runtime/gpu/gpu_device.cc:2251] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...

# %%
import keras

# %%
# %%time

# Train a Gradient Boosted Trees model.
model = tfdf.keras.GradientBoostedTreesModel()

# Add evaluation metrics
model.compile(
    metrics=["accuracy"]
)
model.fit(x=train_ds)

# # Train a Gradient Boosted Trees model.
# model = tfdf.keras.GradientBoostedTreesModel(num_trees=1500)
# model.fit(train_ds)
# Out:
# Use /tmp/tmpmdo3wt_f as temporary training directory
# Reading training dataset...
# [WARNING 26-07-04 09:17:50.1976 UTC gradient_boosted_trees.cc:1840] "goss_alpha" set but "sampling_method" not equal to "GOSS".
# [WARNING 26-07-04 09:17:50.1976 UTC gradient_boosted_trees.cc:1851] "goss_beta" set but "sampling_method" not equal to "GOSS".
# [WARNING 26-07-04 09:17:50.1976 UTC gradient_boosted_trees.cc:1865] "selective_gradient_boosting_ratio" set but "sampling_method" not equal to "SELGB".
# Training dataset read in 0:00:03.057728. Found 395895 examples.
# Training model...
# Model trained in 0:00:54.907144
# Compiling model...
# [INFO 26-07-04 09:18:48.1699 UTC kernel.cc:1233] Loading model from path /tmp/tmpmdo3wt_f/model/ with prefix ab61498d7d36415c
# [INFO 26-07-04 09:18:48.1845 UTC quick_scorer_extended.cc:911] The binary was compiled without AVX2 support, but your CPU supports it. Enable it for faster model inference.
# [INFO 26-07-04 09:18:48.1857 UTC abstract_model.cc:1362] Engine "GradientBoostedTreesQuickScorerExtended" built
# [INFO 26-07-04 09:18:48.1857 UTC kernel.cc:1061] Use fast generic engine
# Model compiled.
# CPU times: user 3min 39s, sys: 1.74 s, total: 3min 41s
# Wall time: 1min

# %%
# Evaluate the model
evaluate = model.evaluate(val_ds, return_dict=True)
print()

for name, value in evaluate.items():
    print(f"{name}: {value:.4f}")
# Out:
# WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
#  1/57 [..............................] - ETA: 2:43 - loss: 0.0000e+00 - accuracy: 0.8630
# 14/57 [======>.......................] - ETA: 0s - loss: 0.0000e+00 - accuracy: 0.8627
# 26/57 [============>.................] - ETA: 0s - loss: 0.0000e+00 - accuracy: 0.8607
# 41/57 [====================>.........] - ETA: 0s - loss: 0.0000e+00 - accuracy: 0.8618
# 56/57 [============================>.] - ETA: 0s - loss: 0.0000e+00 - accuracy: 0.8620
# 57/57 [==============================] - 3s 4ms/step - loss: 0.0000e+00 - accuracy: 0.8619
# loss: 0.0000
# accuracy: 0.8619

# %%
# Model Summary
model.summary()
# Out:
# Model: "gradient_boosted_trees_model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
# =================================================================
# Total params: 1 (1.00 Byte)
# Trainable params: 0 (0.00 Byte)
# Non-trainable params: 1 (1.00 Byte)
# _________________________________________________________________
# Type: "GRADIENT_BOOSTED_TREES"
# Task: CLASSIFICATION
# Label: "__LABEL"
#
# Input Features (5):
# 	Busyness
# 	Coarseness
# 	Complexity
# 	Contrast
# 	Strength
#
# Trained with weights
#
# Variable Importance: INV_MEAN_MIN_DEPTH:
#     1.   "Busyness"  0.341338 ################
#     2. "Complexity"  0.307318 ###########
#     3. "Coarseness"  0.261621 #####
#     4.   "Contrast"  0.245514 ###
#     5.   "Strength"  0.217338
#
# Variable Importance: NUM_AS_ROOT:
#     1.   "Busyness" 99.000000 ################
#     2. "Coarseness" 82.000000 #############
#     3. "Complexity" 73.000000 ###########
#     4.   "Contrast" 44.000000 #######
#     5.   "Strength"  1.000000
#
# Variable Importance: NUM_NODES:
#     1.   "Busyness" 2286.000000 ################
#     2. "Complexity" 1537.000000 ###
#     3.   "Contrast" 1476.000000 ##
#     4. "Coarseness" 1475.000000 ##
#     5.   "Strength" 1300.000000
#
# Variable Importance: SUM_SCORE:
#     1. "Coarseness" 169494.440358 ################
#     2.   "Busyness" 70737.252317 #####
#     3. "Complexity" 32083.465613 #
#     4.   "Strength" 13219.891683
#     5.   "Contrast" 13149.578555
#
#
#
# Loss: BINOMIAL_LOG_LIKELIHOOD
# Validation loss value: 0.671672
# Number of trees per iteration: 1
# Node format: NOT_SET
# Number of trees: 299
# Total number of nodes: 16447
#
# Number of nodes by tree:
# Count: 299 Average: 55.0067 StdDev: 7.50741
# Min: 29 Max: 63 Ignored: 0
# ----------------------------------------------
# [ 29, 30)  4   1.34%   1.34% #
# [ 30, 32)  0   0.00%   1.34%
# [ 32, 34)  0   0.00%   1.34%
# [ 34, 36)  1   0.33%   1.67%
# [ 36, 37)  0   0.00%   1.67%
# [ 37, 39)  1   0.33%   2.01%
# [ 39, 41)  1   0.33%   2.34%
# [ 41, 43)  8   2.68%   5.02% #
# [ 43, 44) 12   4.01%   9.03% ##
# [ 44, 46) 11   3.68%  12.71% ##
# [ 46, 48) 20   6.69%  19.40% ###
# [ 48, 50) 21   7.02%  26.42% ###
# [ 50, 51)  0   0.00%  26.42%
# [ 51, 53) 17   5.69%  32.11% ##
# [ 53, 55) 26   8.70%  40.80% ####
# [ 55, 57) 22   7.36%  48.16% ###
# [ 57, 58) 26   8.70%  56.86% ####
# [ 58, 60) 16   5.35%  62.21% ##
# [ 60, 62) 44  14.72%  76.92% ######
# [ 62, 63] 69  23.08% 100.00% ##########
#
# Depth by leafs:
# Count: 8373 Average: 4.89896 StdDev: 0.402209
# Min: 2 Max: 5 Ignored: 0
# ----------------------------------------------
# [ 2, 3)   52   0.62%   0.62%
# [ 3, 4)  141   1.68%   2.31%
# [ 4, 5)  408   4.87%   7.18% #
# [ 5, 5] 7772  92.82% 100.00% ##########
#
# Number of training obs by leaf:
# Count: 8373 Average: 12719.7 StdDev: 45453.3
# Min: 5 Max: 355908 Ignored: 0
# ----------------------------------------------
# [      5,  17800) 7440  88.86%  88.86% ##########
# [  17800,  35595)  321   3.83%  92.69%
# [  35595,  53390)  129   1.54%  94.23%
# [  53390,  71185)   89   1.06%  95.29%
# [  71185,  88981)   68   0.81%  96.11%
# [  88981, 106776)   32   0.38%  96.49%
# [ 106776, 124571)   31   0.37%  96.86%
# [ 124571, 142366)   20   0.24%  97.10%
# [ 142366, 160161)   25   0.30%  97.40%
# [ 160161, 177957)   13   0.16%  97.55%
# [ 177957, 195752)   26   0.31%  97.86%
# [ 195752, 213547)   21   0.25%  98.11%
# [ 213547, 231342)   20   0.24%  98.35%
# [ 231342, 249137)   28   0.33%  98.69%
# [ 249137, 266933)   11   0.13%  98.82%
# [ 266933, 284728)   17   0.20%  99.02%
# [ 284728, 302523)   14   0.17%  99.19%
# [ 302523, 320318)   14   0.17%  99.36%
# [ 320318, 338113)   18   0.21%  99.57%
# [ 338113, 355908]   36   0.43% 100.00%
#
# Attribute in nodes:
# 	2286 : Busyness [NUMERICAL]
# 	1537 : Complexity [NUMERICAL]
# 	1476 : Contrast [NUMERICAL]
# 	1475 : Coarseness [NUMERICAL]
# 	1300 : Strength [NUMERICAL]
#
# Attribute in nodes with depth <= 0:
# 	99 : Busyness [NUMERICAL]
# 	82 : Coarseness [NUMERICAL]
# 	73 : Complexity [NUMERICAL]
# 	44 : Contrast [NUMERICAL]
# 	1 : Strength [NUMERICAL]
#
# Attribute in nodes with depth <= 1:
# 	257 : Complexity [NUMERICAL]
# 	224 : Busyness [NUMERICAL]
# 	190 : Coarseness [NUMERICAL]
# 	139 : Contrast [NUMERICAL]
# 	87 : Strength [NUMERICAL]
#
# Attribute in nodes with depth <= 2:
# 	570 : Busyness [NUMERICAL]
# 	473 : Complexity [NUMERICAL]
# 	383 : Contrast [NUMERICAL]
# 	359 : Coarseness [NUMERICAL]
# 	256 : Strength [NUMERICAL]
#
# Attribute in nodes with depth <= 3:
# 	1146 : Busyness [NUMERICAL]
# 	843 : Complexity [NUMERICAL]
# 	786 : Contrast [NUMERICAL]
# 	773 : Coarseness [NUMERICAL]
# 	640 : Strength [NUMERICAL]
#
# Attribute in nodes with depth <= 5:
# 	2286 : Busyness [NUMERICAL]
# 	1537 : Complexity [NUMERICAL]
# 	1476 : Contrast [NUMERICAL]
# 	1475 : Coarseness [NUMERICAL]
# 	1300 : Strength [NUMERICAL]
#
# Condition type in nodes:
# 	8074 : HigherCondition
# Condition type in nodes with depth <= 0:
# 	299 : HigherCondition
# Condition type in nodes with depth <= 1:
# 	897 : HigherCondition
# Condition type in nodes with depth <= 2:
# 	2041 : HigherCondition
# Condition type in nodes with depth <= 3:
# 	4188 : HigherCondition
# Condition type in nodes with depth <= 5:
# 	8074 : HigherCondition
#
# Training logs:
# Number of iteration to final model: 299
# 	Iter:1 train-loss:1.297481 valid-loss:1.297587  train-accuracy:0.800321 valid-accuracy:0.805258
# 	Iter:2 train-loss:1.225630 valid-loss:1.226105  train-accuracy:0.814287 valid-accuracy:0.817189
# 	Iter:3 train-loss:1.165224 valid-loss:1.165217  train-accuracy:0.815902 valid-accuracy:0.818873
# 	Iter:4 train-loss:1.114877 valid-loss:1.114713  train-accuracy:0.814603 valid-accuracy:0.820539
# 	Iter:5 train-loss:1.070229 valid-loss:1.069333  train-accuracy:0.819566 valid-accuracy:0.826302
# 	Iter:6 train-loss:1.029640 valid-loss:1.028243  train-accuracy:0.822776 valid-accuracy:0.826694
# 	Iter:16 train-loss:0.832882 valid-loss:0.832866  train-accuracy:0.829565 valid-accuracy:0.831089
# 	Iter:26 train-loss:0.764612 valid-loss:0.768440  train-accuracy:0.836956 valid-accuracy:0.838838
# 	Iter:36 train-loss:0.727939 valid-loss:0.737151  train-accuracy:0.842582 valid-accuracy:0.842812
# 	Iter:46 train-loss:0.708586 valid-loss:0.721365  train-accuracy:0.846075 valid-accuracy:0.844778
# 	Iter:56 train-loss:0.693426 valid-loss:0.709562  train-accuracy:0.849382 valid-accuracy:0.848492
# 	Iter:66 train-loss:0.681657 valid-loss:0.701025  train-accuracy:0.852158 valid-accuracy:0.849675
# 	Iter:76 train-loss:0.671877 valid-loss:0.695108  train-accuracy:0.854411 valid-accuracy:0.848950
# 	Iter:86 train-loss:0.663625 valid-loss:0.690037  train-accuracy:0.856185 valid-accuracy:0.849920
# 	Iter:96 train-loss:0.658519 valid-loss:0.687577  train-accuracy:0.857214 valid-accuracy:0.849615
# 	Iter:106 train-loss:0.652171 valid-loss:0.684724  train-accuracy:0.858481 valid-accuracy:0.849692
# 	Iter:116 train-loss:0.646265 valid-loss:0.682127  train-accuracy:0.860091 valid-accuracy:0.851677
# 	Iter:126 train-loss:0.642309 valid-loss:0.680711  train-accuracy:0.860762 valid-accuracy:0.851958
# 	Iter:136 train-loss:0.636987 valid-loss:0.678237  train-accuracy:0.861896 valid-accuracy:0.852208
# 	Iter:146 train-loss:0.633989 valid-loss:0.677336  train-accuracy:0.862792 valid-accuracy:0.852484
# 	Iter:156 train-loss:0.630471 valid-loss:0.676629  train-accuracy:0.863706 valid-accuracy:0.852427
# 	Iter:166 train-loss:0.627112 valid-loss:0.676228  train-accuracy:0.864491 valid-accuracy:0.852374
# 	Iter:176 train-loss:0.624026 valid-loss:0.675710  train-accuracy:0.865143 valid-accuracy:0.852472
# 	Iter:186 train-loss:0.621039 valid-loss:0.675377  train-accuracy:0.865896 valid-accuracy:0.853197
# 	Iter:196 train-loss:0.618768 valid-loss:0.674747  train-accuracy:0.866191 valid-accuracy:0.852908
# 	Iter:206 train-loss:0.616619 valid-loss:0.674977  train-accuracy:0.866811 valid-accuracy:0.852549
# 	Iter:216 train-loss:0.614580 valid-loss:0.674872  train-accuracy:0.867321 valid-accuracy:0.852718
# 	Iter:226 train-loss:0.611569 valid-loss:0.674421  train-accuracy:0.867971 valid-accuracy:0.852493
# 	Iter:236 train-loss:0.609348 valid-loss:0.674135  train-accuracy:0.868620 valid-accuracy:0.853070
# 	Iter:246 train-loss:0.606628 valid-loss:0.673767  train-accuracy:0.869452 valid-accuracy:0.852463
# 	Iter:256 train-loss:0.603937 valid-loss:0.673554  train-accuracy:0.869951 valid-accuracy:0.852704
# 	Iter:266 train-loss:0.601627 valid-loss:0.673439  train-accuracy:0.870390 valid-accuracy:0.852433
# 	Iter:276 train-loss:0.599534 valid-loss:0.673309  train-accuracy:0.871118 valid-accuracy:0.852856
# 	Iter:286 train-loss:0.596943 valid-loss:0.672930  train-accuracy:0.871693 valid-accuracy:0.853152
# 	Iter:296 train-loss:0.594187 valid-loss:0.671832  train-accuracy:0.872358 valid-accuracy:0.853238

# %%
# Model features
model.make_inspector().features()
# Out:
# ["Busyness" (1; #0),
#  "Coarseness" (1; #1),
#  "Complexity" (1; #2),
#  "Contrast" (1; #3),
#  "Strength" (1; #4)]

# %%
# Feature importance
model.make_inspector().variable_importances()
# Out:
# {'INV_MEAN_MIN_DEPTH': [("Busyness" (1; #0), 0.3413382437399405),
#   ("Complexity" (1; #2), 0.30731750603794095),
#   ("Coarseness" (1; #1), 0.26162086500143017),
#   ("Contrast" (1; #3), 0.24551350645453085),
#   ("Strength" (1; #4), 0.21733790520672602)],
#  'NUM_AS_ROOT': [("Busyness" (1; #0), 99.0),
#   ("Coarseness" (1; #1), 82.0),
#   ("Complexity" (1; #2), 73.0),
#   ("Contrast" (1; #3), 44.0),
#   ("Strength" (1; #4), 1.0)],
#  'SUM_SCORE': [("Coarseness" (1; #1), 169494.44035816283),
#   ("Busyness" (1; #0), 70737.2523170348),
#   ("Complexity" (1; #2), 32083.465613020664),
#   ("Strength" (1; #4), 13219.89168330269),
#   ("Contrast" (1; #3), 13149.57855536485)],
#  'NUM_NODES': [("Busyness" (1; #0), 2286.0),
#   ("Complexity" (1; #2), 1537.0),
#   ("Contrast" (1; #3), 1476.0),
#   ("Coarseness" (1; #1), 1475.0),
#   ("Strength" (1; #4), 1300.0)]}

# %%
# Model self evaluation
model.make_inspector().evaluation()
# Out:
# Evaluation(num_examples=None, accuracy=0.8536649942398071, loss=0.6716722249984741, rmse=None, ndcg=None, aucs=None, auuc=None, qini=None)

# %%
logs = model.make_inspector().training_logs()

plt.figure(figsize=(12, 4))
plt.subplot(1, 2, 1)
plt.plot([log.num_trees for log in logs], [log.evaluation.accuracy for log in logs])
plt.xlabel("Number of trees")
plt.ylabel("Accuracy (out-of-bag)")
plt.subplot(1, 2, 2)
plt.plot([log.num_trees for log in logs], [log.evaluation.loss for log in logs])
plt.xlabel("Number of trees")
plt.ylabel("Logloss (out-of-bag)")
plt.show()

# %% [markdown]
# Calculate the score of our hold-out validation dataset

# %%
predictions = model.predict(val_ds)
y_true      = validation_data["label"]

from sklearn.metrics import roc_auc_score
ROC_AUC = roc_auc_score(y_true, predictions)
print("The ROC AUC score is %.5f" % ROC_AUC )
# Out:
#  1/57 [..............................] - ETA: 3s
# 16/57 [=======>......................] - ETA: 0s
# 30/57 [==============>...............] - ETA: 0s
# 44/57 [======================>.......] - ETA: 0s
# 57/57 [==============================] - 0s 4ms/step
# The ROC AUC score is 0.92968

# %%
# Compute binary classification metrics with sklearn
import numpy as np
from sklearn.metrics import (
    accuracy_score,
    precision_score,
    recall_score,
    f1_score,
    roc_auc_score,
    average_precision_score,
    confusion_matrix,
    classification_report,
    matthews_corrcoef,
    log_loss,
    brier_score_loss,
)

# Get predictions (probabilities or class labels)
preds = model.predict(test_ds)
# If model outputs probabilities, convert to labels by threshold 0.5
if preds.ndim == 2:
    # For TFDF classification, preds may be class probabilities with shape (N, 2)
    if preds.shape[1] == 2:
        pos_probs = preds[:, 1]
    else:
        # If single-probability column (positive class)
        pos_probs = preds[:, -1]
    y_pred = (pos_probs >= 0.5).astype(int)
else:
    # Already class labels
    y_pred = preds.astype(int)
    pos_probs = None

# Ground truth labels (must be 0/1 integers)
y_true = test_data["label"].astype(int).to_numpy()

# Core metrics
metrics = {}
metrics["accuracy"] = accuracy_score(y_true, y_pred)
metrics["precision"] = precision_score(y_true, y_pred, zero_division=0)
metrics["recall"] = recall_score(y_true, y_pred, zero_division=0)
metrics["f1"] = f1_score(y_true, y_pred, zero_division=0)
metrics["mcc"] = matthews_corrcoef(y_true, y_pred)

# Probabilistic metrics (only if we have probabilities)
if pos_probs is not None:
    metrics["roc_auc"] = roc_auc_score(y_true, pos_probs)
    metrics["pr_auc"] = average_precision_score(y_true, pos_probs)
    metrics["log_loss"] = log_loss(y_true, pos_probs, labels=[0,1])
    metrics["brier_score"] = brier_score_loss(y_true, pos_probs)

# Confusion matrix and detailed report
cm = confusion_matrix(y_true, y_pred, labels=[0,1])
report = classification_report(y_true, y_pred, digits=4)

print("Sklearn binary metrics:")
for k, v in metrics.items():
    print(f"{k}: {v:.4f}")
print("\nConfusion matrix:\n", cm)
print("\nClassification report:\n", report)
# Out:
#   1/114 [..............................] - ETA: 6s
#  16/114 [===>..........................] - ETA: 0s
#  28/114 [======>.......................] - ETA: 0s
#  41/114 [=========>....................] - ETA: 0s
#  56/114 [=============>................] - ETA: 0s
#  70/114 [=================>............] - ETA: 0s
#  85/114 [=====================>........] - ETA: 0s
# 100/114 [=========================>....] - ETA: 0s
# 114/114 [==============================] - 0s 4ms/step
# Sklearn binary metrics:
# accuracy: 0.8635
# precision: 0.2988
# recall: 0.8365
# f1: 0.4403
# mcc: 0.4480
# roc_auc: 0.9302
# pr_auc: 0.6141
# log_loss: 0.3149
# brier_score: 0.0978
#
# Confusion matrix:
#  [[91604 14251]
#  [ 1187  6072]]
#
# Classification report:
#                precision    recall  f1-score   support
#
#            0     0.9872    0.8654    0.9223    105855
#            1     0.2988    0.8365    0.4403      7259
#
#     accuracy                         0.8635    113114
#    macro avg     0.6430    0.8509    0.6813    113114
# weighted avg     0.9430    0.8635    0.8914    113114
