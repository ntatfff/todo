# %%
# Import packages and modules
import numpy  as np
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow_decision_forests as tfdf

from sklearn.model_selection import train_test_split
# Out:
# 2026-07-04 08:28:49.793866: I tensorflow/core/util/port.cc:113] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2026-07-04 08:28:49.833277: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2026-07-04 08:28:54.074554: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
# Check the version of TensorFlow Decision Forests
print("Found TensorFlow Decision Forests v" + tfdf.__version__)
# Out:
# Found TensorFlow Decision Forests v1.9.1

# %%
datasetPath = 'dataset/firstorder/kernel5-radius5/dataset.csv'

# %%
# Parameters
datasetPath = "dataset/glcm/kernel5-radius5/300.dataset.csv"

# %%
# train/validation/test = 70/10/20
dataset = pd.read_csv(datasetPath)

train_data, temp_data = train_test_split(dataset, test_size=0.3, random_state=42)
validation_data, test_data = train_test_split(temp_data, test_size=2/3, random_state=42)

# %%
from sklearn.utils.class_weight import compute_class_weight

# tinh class weight tren tap train
classes = np.array([0, 1])
weights = compute_class_weight(class_weight="balanced", classes=classes, y=train_data["label"])
class_weight = {0: weights[0], 1: weights[1]}

# gan sample_weight cho tung dong
train_data["sample_weight"] = train_data["label"].map(class_weight)
validation_data["sample_weight"] = validation_data["label"].map(class_weight)
test_data["sample_weight"] = test_data["label"].map(class_weight)

# Convert the dataset into a TensorFlow dataset.
train_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    train_data, label="label", weight="sample_weight"
)         
val_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    validation_data, label="label", weight="sample_weight"
)
test_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    test_data, label="label", weight="sample_weight"
)
# Out:
# 2026-07-04 08:29:08.198592: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:984] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2026-07-04 08:29:08.200468: W tensorflow/core/common_runtime/gpu/gpu_device.cc:2251] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...

# %%
import keras

# %%
# %%time

# Train a Random Forest model.
model = tfdf.keras.RandomForestModel()

# Add evaluation metrics
model.compile(
    metrics=["accuracy"]
)
model.fit(x=train_ds)

# # Train a Gradient Boosted Trees model.
# model = tfdf.keras.GradientBoostedTreesModel(num_trees=1500)
# model.fit(train_ds)
# Out:
# Use /tmp/tmpj5i4ke0m as temporary training directory
# Reading training dataset...
# Training dataset read in 0:00:03.942953. Found 235478 examples.
# Training model...
# [INFO 26-07-04 08:29:39.4097 UTC kernel.cc:1233] Loading model from path /tmp/tmpj5i4ke0m/model/ with prefix 464fbe0494284209
# [INFO 26-07-04 08:29:40.9095 UTC decision_forest.cc:734] Model loaded with 300 root(s), 1195728 node(s), and 24 input feature(s).
# [INFO 26-07-04 08:29:40.9095 UTC abstract_model.cc:1362] Engine "RandomForestOptPred" built
# [INFO 26-07-04 08:29:40.9096 UTC kernel.cc:1061] Use fast generic engine
# Model trained in 0:00:28.757431
# Compiling model...
# Model compiled.
# CPU times: user 5min 12s, sys: 1.88 s, total: 5min 14s
# Wall time: 35.9 s

# %%
# Evaluate the model
evaluate = model.evaluate(val_ds, return_dict=True)
print()

for name, value in evaluate.items():
    print(f"{name}: {value:.4f}")
# Out:
# WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
#  1/34 [..............................] - ETA: 1:37 - loss: 0.0000e+00 - accuracy: 0.9400
#  3/34 [=>............................] - ETA: 0s - loss: 0.0000e+00 - accuracy: 0.9523
#  5/34 [===>..........................] - ETA: 0s - loss: 0.0000e+00 - accuracy: 0.9558
#  7/34 [=====>........................] - ETA: 0s - loss: 0.0000e+00 - accuracy: 0.9554
#  9/34 [======>.......................] - ETA: 0s - loss: 0.0000e+00 - accuracy: 0.9554
# 11/34 [========>.....................] - ETA: 0s - loss: 0.0000e+00 - accuracy: 0.9550
# 13/34 [==========>...................] - ETA: 0s - loss: 0.0000e+00 - accuracy: 0.9559
# 15/34 [============>.................] - ETA: 0s - loss: 0.0000e+00 - accuracy: 0.9557
# 17/34 [==============>...............] - ETA: 0s - loss: 0.0000e+00 - accuracy: 0.9559
# 19/34 [===============>..............] - ETA: 0s - loss: 0.0000e+00 - accuracy: 0.9558
# 21/34 [=================>............] - ETA: 0s - loss: 0.0000e+00 - accuracy: 0.9559
# 23/34 [===================>..........] - ETA: 0s - loss: 0.0000e+00 - accuracy: 0.9564
# 25/34 [=====================>........] - ETA: 0s - loss: 0.0000e+00 - accuracy: 0.9565
# 27/34 [======================>.......] - ETA: 0s - loss: 0.0000e+00 - accuracy: 0.9566
# 29/34 [========================>.....] - ETA: 0s - loss: 0.0000e+00 - accuracy: 0.9558
# 31/34 [==========================>...] - ETA: 0s - loss: 0.0000e+00 - accuracy: 0.9557
# 33/34 [============================>.] - ETA: 0s - loss: 0.0000e+00 - accuracy: 0.9551
# 34/34 [==============================] - 4s 29ms/step - loss: 0.0000e+00 - accuracy: 0.9554
# loss: 0.0000
# accuracy: 0.9554

# %%
# Model Summary
model.summary()
# Out:
# Model: "random_forest_model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
# =================================================================
# Total params: 1 (1.00 Byte)
# Trainable params: 0 (0.00 Byte)
# Non-trainable params: 1 (1.00 Byte)
# _________________________________________________________________
# Type: "RANDOM_FOREST"
# Task: CLASSIFICATION
# Label: "__LABEL"
#
# Input Features (24):
# 	Autocorrelation
# 	ClusterProminence
# 	ClusterShade
# 	ClusterTendency
# 	Contrast
# 	Correlation
# 	DifferenceAverage
# 	DifferenceEntropy
# 	DifferenceVariance
# 	Id
# 	Idm
# 	Idmn
# 	Idn
# 	Imc1
# 	Imc2
# 	InverseVariance
# 	JointAverage
# 	JointEnergy
# 	JointEntropy
# 	MCC
# 	MaximumProbability
# 	SumAverage
# 	SumEntropy
# 	SumSquares
#
# Trained with weights
#
# Variable Importance: INV_MEAN_MIN_DEPTH:
#     1.    "Autocorrelation"  0.170261 ################
#     2.         "SumAverage"  0.151130 ############
#     3.       "JointAverage"  0.149737 ############
#     4.        "Correlation"  0.140942 ###########
#     5.                "MCC"  0.105133 ####
#     6. "DifferenceVariance"  0.102420 ####
#     7.               "Imc1"  0.101125 ####
#     8.                "Idn"  0.100047 ####
#     9.               "Idmn"  0.093092 ##
#    10.               "Imc2"  0.091355 ##
#    11.           "Contrast"  0.089893 ##
#    12.    "InverseVariance"  0.087803 ##
#    13.       "ClusterShade"  0.087418 ##
#    14.  "DifferenceEntropy"  0.084858 #
#    15.  "DifferenceAverage"  0.083777 #
#    16. "MaximumProbability"  0.082888 #
#    17.        "JointEnergy"  0.080308
#    18.         "SumEntropy"  0.080218
#    19.  "ClusterProminence"  0.079472
#    20.         "SumSquares"  0.077283
#    21.                 "Id"  0.077023
#    22.    "ClusterTendency"  0.076918
#    23.                "Idm"  0.076852
#    24.       "JointEntropy"  0.075565
#
# Variable Importance: NUM_AS_ROOT:
#     1.    "Autocorrelation" 82.000000 ################
#     2.       "JointAverage" 59.000000 ###########
#     3.         "SumAverage" 56.000000 ##########
#     4.        "Correlation" 33.000000 ######
#     5.               "Imc1" 15.000000 ##
#     6.                "MCC" 15.000000 ##
#     7.               "Imc2" 13.000000 ##
#     8.        "JointEnergy"  7.000000 #
#     9.         "SumEntropy"  7.000000 #
#    10. "MaximumProbability"  5.000000
#    11.    "ClusterTendency"  4.000000
#    12.  "ClusterProminence"  2.000000
#    13.       "JointEntropy"  1.000000
#    14.         "SumSquares"  1.000000
#
# Variable Importance: NUM_NODES:
#     1.                "Idn" 44425.000000 ################
#     2.               "Idmn" 41806.000000 ##############
#     3.       "ClusterShade" 36562.000000 ###########
#     4.       "JointAverage" 29673.000000 #######
#     5.         "SumAverage" 29613.000000 #######
#     6.    "Autocorrelation" 29567.000000 #######
#     7.        "Correlation" 26516.000000 #####
#     8. "DifferenceVariance" 26418.000000 #####
#     9.               "Imc1" 25745.000000 #####
#    10.               "Imc2" 24279.000000 ####
#    11.    "InverseVariance" 23120.000000 ###
#    12.                "MCC" 22900.000000 ###
#    13.           "Contrast" 22859.000000 ###
#    14.  "ClusterProminence" 22531.000000 ###
#    15. "MaximumProbability" 22154.000000 ##
#    16.  "DifferenceEntropy" 21193.000000 ##
#    17.         "SumEntropy" 20530.000000 #
#    18.        "JointEnergy" 20285.000000 #
#    19.  "DifferenceAverage" 20111.000000 #
#    20.                "Idm" 17873.000000
#    21.                 "Id" 17751.000000
#    22.       "JointEntropy" 17421.000000
#    23.         "SumSquares" 17241.000000
#    24.    "ClusterTendency" 17141.000000
#
# Variable Importance: SUM_SCORE:
#     1.    "Autocorrelation" 6671042.060360 ################
#     2.         "SumAverage" 5639827.762796 #############
#     3.       "JointAverage" 5612093.359483 #############
#     4.        "Correlation" 3248168.790926 #######
#     5.                "Idn" 2346268.951599 ####
#     6.               "Idmn" 2050158.469055 ####
#     7.               "Imc1" 1884707.785632 ###
#     8.                "MCC" 1802778.739061 ###
#     9. "DifferenceVariance" 1739040.678950 ###
#    10.       "ClusterShade" 1283073.935321 ##
#    11.               "Imc2" 1259806.791298 ##
#    12.    "InverseVariance" 1216933.954989 ##
#    13.           "Contrast" 1188348.351799 ##
#    14.  "DifferenceEntropy" 976652.724785 #
#    15.  "DifferenceAverage" 892210.626712 #
#    16. "MaximumProbability" 848568.313043 #
#    17.         "SumEntropy" 679688.994749
#    18.        "JointEnergy" 671230.344225
#    19.  "ClusterProminence" 624014.891931
#    20.                 "Id" 497923.171198
#    21.         "SumSquares" 495588.258417
#    22.                "Idm" 495106.724097
#    23.    "ClusterTendency" 458453.749779
#    24.       "JointEntropy" 391546.623669
#
#
#
# Winner takes all: true
# Out-of-bag evaluation: accuracy:0.903695 logloss:0.287445
# Number of trees: 300
# Total number of nodes: 1195728
#
# Number of nodes by tree:
# Count: 300 Average: 3985.76 StdDev: 255.761
# Min: 3263 Max: 4713 Ignored: 0
# ----------------------------------------------
# [ 3263, 3335)  2   0.67%   0.67% #
# [ 3335, 3408)  0   0.00%   0.67%
# [ 3408, 3480)  2   0.67%   1.33% #
# [ 3480, 3553)  5   1.67%   3.00% #
# [ 3553, 3625)  9   3.00%   6.00% ###
# [ 3625, 3698) 17   5.67%  11.67% #####
# [ 3698, 3770) 27   9.00%  20.67% ########
# [ 3770, 3843) 32  10.67%  31.33% #########
# [ 3843, 3915) 33  11.00%  42.33% ##########
# [ 3915, 3988) 34  11.33%  53.67% ##########
# [ 3988, 4061) 34  11.33%  65.00% ##########
# [ 4061, 4133) 25   8.33%  73.33% #######
# [ 4133, 4206) 22   7.33%  80.67% ######
# [ 4206, 4278) 16   5.33%  86.00% #####
# [ 4278, 4351) 15   5.00%  91.00% ####
# [ 4351, 4423)  9   3.00%  94.00% ###
# [ 4423, 4496)  6   2.00%  96.00% ##
# [ 4496, 4568)  8   2.67%  98.67% ##
# [ 4568, 4641)  1   0.33%  99.00%
# [ 4641, 4713]  3   1.00% 100.00% #
#
# Depth by leafs:
# Count: 598014 Average: 12.9461 StdDev: 2.09088
# Min: 4 Max: 15 Ignored: 0
# ----------------------------------------------
# [  4,  5)     15   0.00%   0.00%
# [  5,  6)    393   0.07%   0.07%
# [  6,  7)   1934   0.32%   0.39%
# [  7,  8)   6236   1.04%   1.43%
# [  8,  9)  13654   2.28%   3.72% #
# [  9, 10)  24854   4.16%   7.87% #
# [ 10, 11)  39112   6.54%  14.41% ##
# [ 11, 12)  55618   9.30%  23.71% ###
# [ 12, 13)  73126  12.23%  35.94% ####
# [ 13, 14)  87938  14.71%  50.65% ####
# [ 14, 15)  98890  16.54%  67.18% #####
# [ 15, 15] 196244  32.82% 100.00% ##########
#
# Number of training obs by leaf:
# Count: 598014 Average: 118.13 StdDev: 854.473
# Min: 5 Max: 49128 Ignored: 0
# ----------------------------------------------
# [     5,  2461) 593986  99.33%  99.33% ##########
# [  2461,  4917)   2220   0.37%  99.70%
# [  4917,  7373)    736   0.12%  99.82%
# [  7373,  9829)    307   0.05%  99.87%
# [  9829, 12286)    212   0.04%  99.91%
# [ 12286, 14742)    150   0.03%  99.93%
# [ 14742, 17198)     63   0.01%  99.94%
# [ 17198, 19654)     52   0.01%  99.95%
# [ 19654, 22110)     51   0.01%  99.96%
# [ 22110, 24567)     43   0.01%  99.97%
# [ 24567, 27023)     35   0.01%  99.97%
# [ 27023, 29479)     33   0.01%  99.98%
# [ 29479, 31935)     32   0.01%  99.98%
# [ 31935, 34391)     21   0.00%  99.99%
# [ 34391, 36848)     26   0.00%  99.99%
# [ 36848, 39304)     14   0.00%  99.99%
# [ 39304, 41760)     23   0.00% 100.00%
# [ 41760, 44216)      8   0.00% 100.00%
# [ 44216, 46672)      1   0.00% 100.00%
# [ 46672, 49128]      1   0.00% 100.00%
#
# Attribute in nodes:
# 	44425 : Idn [NUMERICAL]
# 	41806 : Idmn [NUMERICAL]
# 	36562 : ClusterShade [NUMERICAL]
# 	29673 : JointAverage [NUMERICAL]
# 	29613 : SumAverage [NUMERICAL]
# 	29567 : Autocorrelation [NUMERICAL]
# 	26516 : Correlation [NUMERICAL]
# 	26418 : DifferenceVariance [NUMERICAL]
# 	25745 : Imc1 [NUMERICAL]
# 	24279 : Imc2 [NUMERICAL]
# 	23120 : InverseVariance [NUMERICAL]
# 	22900 : MCC [NUMERICAL]
# 	22859 : Contrast [NUMERICAL]
# 	22531 : ClusterProminence [NUMERICAL]
# 	22154 : MaximumProbability [NUMERICAL]
# 	21193 : DifferenceEntropy [NUMERICAL]
# 	20530 : SumEntropy [NUMERICAL]
# 	20285 : JointEnergy [NUMERICAL]
# 	20111 : DifferenceAverage [NUMERICAL]
# 	17873 : Idm [NUMERICAL]
# 	17751 : Id [NUMERICAL]
# 	17421 : JointEntropy [NUMERICAL]
# 	17241 : SumSquares [NUMERICAL]
# 	17141 : ClusterTendency [NUMERICAL]
#
# Attribute in nodes with depth <= 0:
# 	82 : Autocorrelation [NUMERICAL]
# 	59 : JointAverage [NUMERICAL]
# 	56 : SumAverage [NUMERICAL]
# 	33 : Correlation [NUMERICAL]
# 	15 : MCC [NUMERICAL]
# 	15 : Imc1 [NUMERICAL]
# 	13 : Imc2 [NUMERICAL]
# 	7 : SumEntropy [NUMERICAL]
# 	7 : JointEnergy [NUMERICAL]
# 	5 : MaximumProbability [NUMERICAL]
# 	4 : ClusterTendency [NUMERICAL]
# 	2 : ClusterProminence [NUMERICAL]
# 	1 : SumSquares [NUMERICAL]
# 	1 : JointEntropy [NUMERICAL]
#
# Attribute in nodes with depth <= 1:
# 	156 : Autocorrelation [NUMERICAL]
# 	154 : Correlation [NUMERICAL]
# 	123 : JointAverage [NUMERICAL]
# 	116 : SumAverage [NUMERICAL]
# 	98 : MCC [NUMERICAL]
# 	97 : Imc1 [NUMERICAL]
# 	55 : Imc2 [NUMERICAL]
# 	17 : Idn [NUMERICAL]
# 	16 : MaximumProbability [NUMERICAL]
# 	14 : SumEntropy [NUMERICAL]
# 	11 : JointEnergy [NUMERICAL]
# 	7 : ClusterTendency [NUMERICAL]
# 	6 : Idmn [NUMERICAL]
# 	6 : DifferenceVariance [NUMERICAL]
# 	5 : InverseVariance [NUMERICAL]
# 	5 : DifferenceAverage [NUMERICAL]
# 	4 : ClusterProminence [NUMERICAL]
# 	3 : JointEntropy [NUMERICAL]
# 	3 : Contrast [NUMERICAL]
# 	2 : DifferenceEntropy [NUMERICAL]
# 	1 : SumSquares [NUMERICAL]
# 	1 : Id [NUMERICAL]
#
# Attribute in nodes with depth <= 2:
# 	304 : Autocorrelation [NUMERICAL]
# 	281 : Correlation [NUMERICAL]
# 	277 : SumAverage [NUMERICAL]
# 	267 : JointAverage [NUMERICAL]
# 	179 : Imc1 [NUMERICAL]
# 	147 : MCC [NUMERICAL]
# 	97 : DifferenceVariance [NUMERICAL]
# 	86 : Imc2 [NUMERICAL]
# 	64 : Contrast [NUMERICAL]
# 	62 : Idn [NUMERICAL]
# 	61 : InverseVariance [NUMERICAL]
# 	45 : DifferenceEntropy [NUMERICAL]
# 	44 : DifferenceAverage [NUMERICAL]
# 	33 : MaximumProbability [NUMERICAL]
# 	33 : Idmn [NUMERICAL]
# 	24 : Id [NUMERICAL]
# 	20 : JointEnergy [NUMERICAL]
# 	19 : SumEntropy [NUMERICAL]
# 	18 : Idm [NUMERICAL]
# 	12 : SumSquares [NUMERICAL]
# 	10 : ClusterTendency [NUMERICAL]
# 	8 : ClusterProminence [NUMERICAL]
# 	6 : ClusterShade [NUMERICAL]
# 	3 : JointEntropy [NUMERICAL]
#
# Attribute in nodes with depth <= 3:
# 	606 : SumAverage [NUMERICAL]
# 	588 : Autocorrelation [NUMERICAL]
# 	537 : JointAverage [NUMERICAL]
# 	423 : Correlation [NUMERICAL]
# 	301 : Imc1 [NUMERICAL]
# 	254 : DifferenceVariance [NUMERICAL]
# 	213 : MCC [NUMERICAL]
# 	191 : Idn [NUMERICAL]
# 	175 : Contrast [NUMERICAL]
# 	167 : DifferenceEntropy [NUMERICAL]
# 	152 : InverseVariance [NUMERICAL]
# 	141 : Imc2 [NUMERICAL]
# 	137 : DifferenceAverage [NUMERICAL]
# 	103 : Idmn [NUMERICAL]
# 	95 : Id [NUMERICAL]
# 	84 : Idm [NUMERICAL]
# 	75 : MaximumProbability [NUMERICAL]
# 	45 : JointEnergy [NUMERICAL]
# 	44 : SumEntropy [NUMERICAL]
# 	42 : SumSquares [NUMERICAL]
# 	38 : ClusterProminence [NUMERICAL]
# 	36 : ClusterShade [NUMERICAL]
# 	33 : ClusterTendency [NUMERICAL]
# 	20 : JointEntropy [NUMERICAL]
#
# Attribute in nodes with depth <= 5:
# 	1893 : SumAverage [NUMERICAL]
# 	1834 : JointAverage [NUMERICAL]
# 	1794 : Autocorrelation [NUMERICAL]
# 	1353 : Idn [NUMERICAL]
# 	1207 : Correlation [NUMERICAL]
# 	1189 : Idmn [NUMERICAL]
# 	945 : Imc1 [NUMERICAL]
# 	937 : DifferenceVariance [NUMERICAL]
# 	766 : Contrast [NUMERICAL]
# 	723 : DifferenceEntropy [NUMERICAL]
# 	635 : InverseVariance [NUMERICAL]
# 	622 : Imc2 [NUMERICAL]
# 	610 : DifferenceAverage [NUMERICAL]
# 	542 : MCC [NUMERICAL]
# 	536 : ClusterShade [NUMERICAL]
# 	450 : Idm [NUMERICAL]
# 	424 : Id [NUMERICAL]
# 	372 : MaximumProbability [NUMERICAL]
# 	333 : SumEntropy [NUMERICAL]
# 	320 : JointEnergy [NUMERICAL]
# 	291 : ClusterProminence [NUMERICAL]
# 	258 : SumSquares [NUMERICAL]
# 	228 : ClusterTendency [NUMERICAL]
# 	200 : JointEntropy [NUMERICAL]
#
# Condition type in nodes:
# 	597714 : HigherCondition
# Condition type in nodes with depth <= 0:
# 	300 : HigherCondition
# Condition type in nodes with depth <= 1:
# 	900 : HigherCondition
# Condition type in nodes with depth <= 2:
# 	2100 : HigherCondition
# Condition type in nodes with depth <= 3:
# 	4500 : HigherCondition
# Condition type in nodes with depth <= 5:
# 	18462 : HigherCondition
# Node format: NOT_SET
#
# Training OOB:
# 	trees: 1, Out-of-bag evaluation: accuracy:0.870482 logloss:4.6683
# 	trees: 11, Out-of-bag evaluation: accuracy:0.877688 logloss:1.6738
# 	trees: 21, Out-of-bag evaluation: accuracy:0.891416 logloss:0.993338
# 	trees: 31, Out-of-bag evaluation: accuracy:0.8962 logloss:0.734265
# 	trees: 41, Out-of-bag evaluation: accuracy:0.899212 logloss:0.613638
# 	trees: 51, Out-of-bag evaluation: accuracy:0.900269 logloss:0.546454
# 	trees: 61, Out-of-bag evaluation: accuracy:0.901792 logloss:0.500384
# 	trees: 71, Out-of-bag evaluation: accuracy:0.902104 logloss:0.46804
# 	trees: 81, Out-of-bag evaluation: accuracy:0.902752 logloss:0.43709
# 	trees: 91, Out-of-bag evaluation: accuracy:0.903143 logloss:0.412884
# 	trees: 101, Out-of-bag evaluation: accuracy:0.902644 logloss:0.393132
# 	trees: 111, Out-of-bag evaluation: accuracy:0.902632 logloss:0.381943
# 	trees: 121, Out-of-bag evaluation: accuracy:0.902704 logloss:0.371138
# 	trees: 131, Out-of-bag evaluation: accuracy:0.902803 logloss:0.362262
# 	trees: 141, Out-of-bag evaluation: accuracy:0.902823 logloss:0.351727
# 	trees: 151, Out-of-bag evaluation: accuracy:0.902851 logloss:0.33837
# 	trees: 161, Out-of-bag evaluation: accuracy:0.902943 logloss:0.331658
# 	trees: 171, Out-of-bag evaluation: accuracy:0.903239 logloss:0.329591
# 	trees: 181, Out-of-bag evaluation: accuracy:0.903387 logloss:0.322703
# 	trees: 191, Out-of-bag evaluation: accuracy:0.903383 logloss:0.318849
# 	trees: 201, Out-of-bag evaluation: accuracy:0.903205 logloss:0.314939
# 	trees: 211, Out-of-bag evaluation: accuracy:0.903128 logloss:0.313175
# 	trees: 221, Out-of-bag evaluation: accuracy:0.90314 logloss:0.309382
# 	trees: 231, Out-of-bag evaluation: accuracy:0.903076 logloss:0.304196
# 	trees: 241, Out-of-bag evaluation: accuracy:0.90339 logloss:0.30361
# 	trees: 251, Out-of-bag evaluation: accuracy:0.903322 logloss:0.300955
# 	trees: 261, Out-of-bag evaluation: accuracy:0.903318 logloss:0.296248
# 	trees: 271, Out-of-bag evaluation: accuracy:0.903517 logloss:0.293662
# 	trees: 281, Out-of-bag evaluation: accuracy:0.903767 logloss:0.291049
# 	trees: 291, Out-of-bag evaluation: accuracy:0.903568 logloss:0.288692
# 	trees: 300, Out-of-bag evaluation: accuracy:0.903695 logloss:0.287445

# %%
# Model features
model.make_inspector().features()
# Out:
# ["Autocorrelation" (1; #0),
#  "ClusterProminence" (1; #1),
#  "ClusterShade" (1; #2),
#  "ClusterTendency" (1; #3),
#  "Contrast" (1; #4),
#  "Correlation" (1; #5),
#  "DifferenceAverage" (1; #6),
#  "DifferenceEntropy" (1; #7),
#  "DifferenceVariance" (1; #8),
#  "Id" (1; #9),
#  "Idm" (1; #10),
#  "Idmn" (1; #11),
#  "Idn" (1; #12),
#  "Imc1" (1; #13),
#  "Imc2" (1; #14),
#  "InverseVariance" (1; #15),
#  "JointAverage" (1; #16),
#  "JointEnergy" (1; #17),
#  "JointEntropy" (1; #18),
#  "MCC" (1; #19),
#  "MaximumProbability" (1; #20),
#  "SumAverage" (1; #21),
#  "SumEntropy" (1; #22),
#  "SumSquares" (1; #23)]

# %%
# Feature importance
model.make_inspector().variable_importances()
# Out:
# {'INV_MEAN_MIN_DEPTH': [("Autocorrelation" (1; #0), 0.17026099058096594),
#   ("SumAverage" (1; #21), 0.15113006801712955),
#   ("JointAverage" (1; #16), 0.14973713926789875),
#   ("Correlation" (1; #5), 0.14094158619856392),
#   ("MCC" (1; #19), 0.10513319771297593),
#   ("DifferenceVariance" (1; #8), 0.10241957807758105),
#   ("Imc1" (1; #13), 0.10112497497687693),
#   ("Idn" (1; #12), 0.10004713437432727),
#   ("Idmn" (1; #11), 0.09309176126309324),
#   ("Imc2" (1; #14), 0.09135523044374415),
#   ("Contrast" (1; #4), 0.08989263963433877),
#   ("InverseVariance" (1; #15), 0.08780328304001063),
#   ("ClusterShade" (1; #2), 0.0874179656559859),
#   ("DifferenceEntropy" (1; #7), 0.08485812887034415),
#   ("DifferenceAverage" (1; #6), 0.08377737404098938),
#   ("MaximumProbability" (1; #20), 0.08288815892582826),
#   ("JointEnergy" (1; #17), 0.08030814780240635),
#   ("SumEntropy" (1; #22), 0.08021786727442666),
#   ("ClusterProminence" (1; #1), 0.07947186396346667),
#   ("SumSquares" (1; #23), 0.07728298843077294),
#   ("Id" (1; #9), 0.07702313980763877),
#   ("ClusterTendency" (1; #3), 0.0769178818664178),
#   ("Idm" (1; #10), 0.07685242237459323),
#   ("JointEntropy" (1; #18), 0.0755645840336514)],
#  'SUM_SCORE': [("Autocorrelation" (1; #0), 6671042.060360231),
#   ("SumAverage" (1; #21), 5639827.762795941),
#   ("JointAverage" (1; #16), 5612093.359482874),
#   ("Correlation" (1; #5), 3248168.7909256383),
#   ("Idn" (1; #12), 2346268.951598752),
#   ("Idmn" (1; #11), 2050158.4690549541),
#   ("Imc1" (1; #13), 1884707.7856316052),
#   ("MCC" (1; #19), 1802778.7390610415),
#   ("DifferenceVariance" (1; #8), 1739040.6789495503),
#   ("ClusterShade" (1; #2), 1283073.935321106),
#   ("Imc2" (1; #14), 1259806.7912980278),
#   ("InverseVariance" (1; #15), 1216933.9549886375),
#   ("Contrast" (1; #4), 1188348.3517987803),
#   ("DifferenceEntropy" (1; #7), 976652.7247852462),
#   ("DifferenceAverage" (1; #6), 892210.6267120737),
#   ("MaximumProbability" (1; #20), 848568.3130433579),
#   ("SumEntropy" (1; #22), 679688.9947493338),
#   ("JointEnergy" (1; #17), 671230.3442247331),
#   ("ClusterProminence" (1; #1), 624014.8919306464),
#   ("Id" (1; #9), 497923.1711978623),
#   ("SumSquares" (1; #23), 495588.25841660256),
#   ("Idm" (1; #10), 495106.7240974565),
#   ("ClusterTendency" (1; #3), 458453.74977895396),
#   ("JointEntropy" (1; #18), 391546.62366851774)],
#  'NUM_AS_ROOT': [("Autocorrelation" (1; #0), 82.0),
#   ("JointAverage" (1; #16), 59.0),
#   ("SumAverage" (1; #21), 56.0),
#   ("Correlation" (1; #5), 33.0),
#   ("Imc1" (1; #13), 15.0),
#   ("MCC" (1; #19), 15.0),
#   ("Imc2" (1; #14), 13.0),
#   ("JointEnergy" (1; #17), 7.0),
#   ("SumEntropy" (1; #22), 7.0),
#   ("MaximumProbability" (1; #20), 5.0),
#   ("ClusterTendency" (1; #3), 4.0),
#   ("ClusterProminence" (1; #1), 2.0),
#   ("JointEntropy" (1; #18), 1.0),
#   ("SumSquares" (1; #23), 1.0)],
#  'NUM_NODES': [("Idn" (1; #12), 44425.0),
#   ("Idmn" (1; #11), 41806.0),
#   ("ClusterShade" (1; #2), 36562.0),
#   ("JointAverage" (1; #16), 29673.0),
#   ("SumAverage" (1; #21), 29613.0),
#   ("Autocorrelation" (1; #0), 29567.0),
#   ("Correlation" (1; #5), 26516.0),
#   ("DifferenceVariance" (1; #8), 26418.0),
#   ("Imc1" (1; #13), 25745.0),
#   ("Imc2" (1; #14), 24279.0),
#   ("InverseVariance" (1; #15), 23120.0),
#   ("MCC" (1; #19), 22900.0),
#   ("Contrast" (1; #4), 22859.0),
#   ("ClusterProminence" (1; #1), 22531.0),
#   ("MaximumProbability" (1; #20), 22154.0),
#   ("DifferenceEntropy" (1; #7), 21193.0),
#   ("SumEntropy" (1; #22), 20530.0),
#   ("JointEnergy" (1; #17), 20285.0),
#   ("DifferenceAverage" (1; #6), 20111.0),
#   ("Idm" (1; #10), 17873.0),
#   ("Id" (1; #9), 17751.0),
#   ("JointEntropy" (1; #18), 17421.0),
#   ("SumSquares" (1; #23), 17241.0),
#   ("ClusterTendency" (1; #3), 17141.0)]}

# %%
# Model self evaluation
model.make_inspector().evaluation()
# Out:
# Evaluation(num_examples=235478, accuracy=0.9036945195521828, loss=0.28744487502055704, rmse=None, ndcg=None, aucs=None, auuc=None, qini=None)

# %%
logs = model.make_inspector().training_logs()

plt.figure(figsize=(12, 4))
plt.subplot(1, 2, 1)
plt.plot([log.num_trees for log in logs], [log.evaluation.accuracy for log in logs])
plt.xlabel("Number of trees")
plt.ylabel("Accuracy (out-of-bag)")
plt.subplot(1, 2, 2)
plt.plot([log.num_trees for log in logs], [log.evaluation.loss for log in logs])
plt.xlabel("Number of trees")
plt.ylabel("Logloss (out-of-bag)")
plt.show()

# %% [markdown]
# Calculate the score of our hold-out validation dataset

# %%
predictions = model.predict(val_ds)
y_true      = validation_data["label"]

from sklearn.metrics import roc_auc_score
ROC_AUC = roc_auc_score(y_true, predictions)
print("The ROC AUC score is %.5f" % ROC_AUC )
# Out:
#  1/34 [..............................] - ETA: 3s
#  3/34 [=>............................] - ETA: 1s
#  5/34 [===>..........................] - ETA: 0s
#  7/34 [=====>........................] - ETA: 0s
#  9/34 [======>.......................] - ETA: 0s
# 11/34 [========>.....................] - ETA: 0s
# 13/34 [==========>...................] - ETA: 0s
# 15/34 [============>.................] - ETA: 0s
# 17/34 [==============>...............] - ETA: 0s
# 19/34 [===============>..............] - ETA: 0s
# 21/34 [=================>............] - ETA: 0s
# 23/34 [===================>..........] - ETA: 0s
# 25/34 [=====================>........] - ETA: 0s
# 27/34 [======================>.......] - ETA: 0s
# 29/34 [========================>.....] - ETA: 0s
# 31/34 [==========================>...] - ETA: 0s
# 33/34 [============================>.] - ETA: 0s
# 34/34 [==============================] - 1s 30ms/step
# The ROC AUC score is 0.97649

# %%
# Compute binary classification metrics with sklearn
import numpy as np
from sklearn.metrics import (
    accuracy_score,
    precision_score,
    recall_score,
    f1_score,
    roc_auc_score,
    average_precision_score,
    confusion_matrix,
    classification_report,
    matthews_corrcoef,
    log_loss,
    brier_score_loss,
)

# Get predictions (probabilities or class labels)
preds = model.predict(test_ds)
# If model outputs probabilities, convert to labels by threshold 0.5
if preds.ndim == 2:
    # For TFDF classification, preds may be class probabilities with shape (N, 2)
    if preds.shape[1] == 2:
        pos_probs = preds[:, 1]
    else:
        # If single-probability column (positive class)
        pos_probs = preds[:, -1]
    y_pred = (pos_probs >= 0.5).astype(int)
else:
    # Already class labels
    y_pred = preds.astype(int)
    pos_probs = None

# Ground truth labels (must be 0/1 integers)
y_true = test_data["label"].astype(int).to_numpy()

# Core metrics
metrics = {}
metrics["accuracy"] = accuracy_score(y_true, y_pred)
metrics["precision"] = precision_score(y_true, y_pred, zero_division=0)
metrics["recall"] = recall_score(y_true, y_pred, zero_division=0)
metrics["f1"] = f1_score(y_true, y_pred, zero_division=0)
metrics["mcc"] = matthews_corrcoef(y_true, y_pred)

# Probabilistic metrics (only if we have probabilities)
if pos_probs is not None:
    metrics["roc_auc"] = roc_auc_score(y_true, pos_probs)
    metrics["pr_auc"] = average_precision_score(y_true, pos_probs)
    metrics["log_loss"] = log_loss(y_true, pos_probs, labels=[0,1])
    metrics["brier_score"] = brier_score_loss(y_true, pos_probs)

# Confusion matrix and detailed report
cm = confusion_matrix(y_true, y_pred, labels=[0,1])
report = classification_report(y_true, y_pred, digits=4)

print("Sklearn binary metrics:")
for k, v in metrics.items():
    print(f"{k}: {v:.4f}")
print("\nConfusion matrix:\n", cm)
print("\nClassification report:\n", report)
# Out:
#  1/68 [..............................] - ETA: 6s
#  3/68 [>.............................] - ETA: 1s
#  5/68 [=>............................] - ETA: 1s
#  7/68 [==>...........................] - ETA: 1s
#  9/68 [==>...........................] - ETA: 1s
# 11/68 [===>..........................] - ETA: 1s
# 13/68 [====>.........................] - ETA: 1s
# 15/68 [=====>........................] - ETA: 1s
# 17/68 [======>.......................] - ETA: 1s
# 19/68 [=======>......................] - ETA: 1s
# 21/68 [========>.....................] - ETA: 1s
# 23/68 [=========>....................] - ETA: 1s
# 25/68 [==========>...................] - ETA: 1s
# 27/68 [==========>...................] - ETA: 1s
# 29/68 [===========>..................] - ETA: 1s
# 31/68 [============>.................] - ETA: 1s
# 33/68 [=============>................] - ETA: 1s
# 35/68 [==============>...............] - ETA: 0s
# 37/68 [===============>..............] - ETA: 0s
# 39/68 [================>.............] - ETA: 0s
# 41/68 [=================>............] - ETA: 0s
# 43/68 [=================>............] - ETA: 0s
# 45/68 [==================>...........] - ETA: 0s
# 47/68 [===================>..........] - ETA: 0s
# 49/68 [====================>.........] - ETA: 0s
# 51/68 [=====================>........] - ETA: 0s
# 53/68 [======================>.......] - ETA: 0s
# 55/68 [=======================>......] - ETA: 0s
# 57/68 [========================>.....] - ETA: 0s
# 59/68 [=========================>....] - ETA: 0s
# 61/68 [=========================>....] - ETA: 0s
# 63/68 [==========================>...] - ETA: 0s
# 65/68 [===========================>..] - ETA: 0s
# 67/68 [============================>.] - ETA: 0s
# 68/68 [==============================] - 2s 29ms/step
# Sklearn binary metrics:
# accuracy: 0.9542
# precision: 0.5824
# recall: 0.8485
# f1: 0.6907
# mcc: 0.6807
# roc_auc: 0.9764
# pr_auc: 0.7912
# log_loss: 0.1212
# brier_score: 0.0344
#
# Confusion matrix:
#  [[60752  2469]
#  [  615  3444]]
#
# Classification report:
#                precision    recall  f1-score   support
#
#            0     0.9900    0.9609    0.9752     63221
#            1     0.5824    0.8485    0.6907      4059
#
#     accuracy                         0.9542     67280
#    macro avg     0.7862    0.9047    0.8330     67280
# weighted avg     0.9654    0.9542    0.9581     67280
