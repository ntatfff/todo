# %%
# Import packages and modules
import numpy  as np
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow_decision_forests as tfdf

from sklearn.model_selection import train_test_split
# Out:
# 2026-07-04 08:59:57.545133: I tensorflow/core/util/port.cc:113] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2026-07-04 08:59:57.585767: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2026-07-04 09:00:02.035431: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
# Check the version of TensorFlow Decision Forests
print("Found TensorFlow Decision Forests v" + tfdf.__version__)
# Out:
# Found TensorFlow Decision Forests v1.9.1

# %%
datasetPath = 'dataset/firstorder/kernel5-radius5/dataset.csv'

# %%
# Parameters
datasetPath = "dataset/glszm/kernel5-radius5/100.dataset.csv"

# %%
# train/validation/test = 70/10/20
dataset = pd.read_csv(datasetPath)

train_data, temp_data = train_test_split(dataset, test_size=0.3, random_state=42)
validation_data, test_data = train_test_split(temp_data, test_size=2/3, random_state=42)

# %%
from sklearn.utils.class_weight import compute_class_weight

# tinh class weight tren tap train
classes = np.array([0, 1])
weights = compute_class_weight(class_weight="balanced", classes=classes, y=train_data["label"])
class_weight = {0: weights[0], 1: weights[1]}

# gan sample_weight cho tung dong
train_data["sample_weight"] = train_data["label"].map(class_weight)
validation_data["sample_weight"] = validation_data["label"].map(class_weight)
test_data["sample_weight"] = test_data["label"].map(class_weight)

# Convert the dataset into a TensorFlow dataset.
train_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    train_data, label="label", weight="sample_weight"
)         
val_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    validation_data, label="label", weight="sample_weight"
)
test_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    test_data, label="label", weight="sample_weight"
)
# Out:
# 2026-07-04 09:00:15.887043: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:984] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2026-07-04 09:00:15.889962: W tensorflow/core/common_runtime/gpu/gpu_device.cc:2251] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...

# %%
import keras

# %%
# %%time

# Train a Gradient Boosted Trees model.
model = tfdf.keras.GradientBoostedTreesModel()

# Add evaluation metrics
model.compile(
    metrics=["accuracy"]
)
model.fit(x=train_ds)

# # Train a Gradient Boosted Trees model.
# model = tfdf.keras.GradientBoostedTreesModel(num_trees=1500)
# model.fit(train_ds)
# Out:
# Use /tmp/tmp9v04x7yj as temporary training directory
# Reading training dataset...
# [WARNING 26-07-04 09:00:16.0346 UTC gradient_boosted_trees.cc:1840] "goss_alpha" set but "sampling_method" not equal to "GOSS".
# [WARNING 26-07-04 09:00:16.0346 UTC gradient_boosted_trees.cc:1851] "goss_beta" set but "sampling_method" not equal to "GOSS".
# [WARNING 26-07-04 09:00:16.0346 UTC gradient_boosted_trees.cc:1865] "selective_gradient_boosting_ratio" set but "sampling_method" not equal to "SELGB".
# Training dataset read in 0:00:02.795479. Found 78712 examples.
# Training model...
# Model trained in 0:00:09.826531
# Compiling model...
# [INFO 26-07-04 09:00:28.6750 UTC kernel.cc:1233] Loading model from path /tmp/tmp9v04x7yj/model/ with prefix 1993c9fe8c12404e
# [INFO 26-07-04 09:00:28.6818 UTC quick_scorer_extended.cc:911] The binary was compiled without AVX2 support, but your CPU supports it. Enable it for faster model inference.
# [INFO 26-07-04 09:00:28.6824 UTC abstract_model.cc:1362] Engine "GradientBoostedTreesQuickScorerExtended" built
# [INFO 26-07-04 09:00:28.6824 UTC kernel.cc:1061] Use fast generic engine
# Model compiled.
# CPU times: user 1min 14s, sys: 1.57 s, total: 1min 16s
# Wall time: 15.7 s

# %%
# Evaluate the model
evaluate = model.evaluate(val_ds, return_dict=True)
print()

for name, value in evaluate.items():
    print(f"{name}: {value:.4f}")
# Out:
# WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
#  1/12 [=>............................] - ETA: 32s - loss: 0.0000e+00 - accuracy: 0.8970
# 12/12 [==============================] - 3s 5ms/step - loss: 0.0000e+00 - accuracy: 0.9024
# loss: 0.0000
# accuracy: 0.9024

# %%
# Model Summary
model.summary()
# Out:
# Model: "gradient_boosted_trees_model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
# =================================================================
# Total params: 1 (1.00 Byte)
# Trainable params: 0 (0.00 Byte)
# Non-trainable params: 1 (1.00 Byte)
# _________________________________________________________________
# Type: "GRADIENT_BOOSTED_TREES"
# Task: CLASSIFICATION
# Label: "__LABEL"
#
# Input Features (16):
# 	GrayLevelNonUniformity
# 	GrayLevelNonUniformityNormalized
# 	GrayLevelVariance
# 	HighGrayLevelZoneEmphasis
# 	LargeAreaEmphasis
# 	LargeAreaHighGrayLevelEmphasis
# 	LargeAreaLowGrayLevelEmphasis
# 	LowGrayLevelZoneEmphasis
# 	SizeZoneNonUniformity
# 	SizeZoneNonUniformityNormalized
# 	SmallAreaEmphasis
# 	SmallAreaHighGrayLevelEmphasis
# 	SmallAreaLowGrayLevelEmphasis
# 	ZoneEntropy
# 	ZonePercentage
# 	ZoneVariance
#
# Trained with weights
#
# Variable Importance: INV_MEAN_MIN_DEPTH:
#     1.   "LargeAreaHighGrayLevelEmphasis"  0.289169 ################
#     2.        "HighGrayLevelZoneEmphasis"  0.250028 ##########
#     3.           "GrayLevelNonUniformity"  0.233266 ########
#     4.    "LargeAreaLowGrayLevelEmphasis"  0.219641 ######
#     5.                     "ZoneVariance"  0.202469 ###
#     6.         "LowGrayLevelZoneEmphasis"  0.200031 ###
#     7.                      "ZoneEntropy"  0.188158 #
#     8.                "GrayLevelVariance"  0.187944 #
#     9.  "SizeZoneNonUniformityNormalized"  0.183017 #
#    10.   "SmallAreaHighGrayLevelEmphasis"  0.182746 #
#    11.    "SmallAreaLowGrayLevelEmphasis"  0.181138
#    12. "GrayLevelNonUniformityNormalized"  0.180895
#    13.                "LargeAreaEmphasis"  0.177877
#    14.                "SmallAreaEmphasis"  0.176825
#    15.                   "ZonePercentage"  0.175870
#    16.            "SizeZoneNonUniformity"  0.175583
#
# Variable Importance: NUM_AS_ROOT:
#     1.  "LargeAreaHighGrayLevelEmphasis" 51.000000 ################
#     2.       "HighGrayLevelZoneEmphasis" 39.000000 ############
#     3.          "GrayLevelNonUniformity" 19.000000 #####
#     4.   "LargeAreaLowGrayLevelEmphasis"  9.000000 ##
#     5.        "LowGrayLevelZoneEmphasis"  7.000000 #
#     6.                    "ZoneVariance"  4.000000
#     7.  "SmallAreaHighGrayLevelEmphasis"  2.000000
#     8.   "SmallAreaLowGrayLevelEmphasis"  2.000000
#     9.               "GrayLevelVariance"  1.000000
#    10. "SizeZoneNonUniformityNormalized"  1.000000
#    11.               "SmallAreaEmphasis"  1.000000
#
# Variable Importance: NUM_NODES:
#     1.   "LargeAreaHighGrayLevelEmphasis" 415.000000 ################
#     2.    "LargeAreaLowGrayLevelEmphasis" 396.000000 ###############
#     3.           "GrayLevelNonUniformity" 395.000000 ###############
#     4.        "HighGrayLevelZoneEmphasis" 367.000000 #############
#     5.         "LowGrayLevelZoneEmphasis" 307.000000 ###########
#     6.                      "ZoneEntropy" 262.000000 ########
#     7.                     "ZoneVariance" 248.000000 ########
#     8.                "GrayLevelVariance" 213.000000 ######
#     9.   "SmallAreaHighGrayLevelEmphasis" 200.000000 ######
#    10.    "SmallAreaLowGrayLevelEmphasis" 181.000000 #####
#    11. "GrayLevelNonUniformityNormalized" 169.000000 ####
#    12.  "SizeZoneNonUniformityNormalized" 118.000000 ##
#    13.            "SizeZoneNonUniformity" 101.000000 #
#    14.                "LargeAreaEmphasis" 92.000000 #
#    15.                "SmallAreaEmphasis" 83.000000
#    16.                   "ZonePercentage" 67.000000
#
# Variable Importance: SUM_SCORE:
#     1.        "HighGrayLevelZoneEmphasis" 31279.257525 ################
#     2.           "GrayLevelNonUniformity" 9389.066161 ####
#     3.   "LargeAreaHighGrayLevelEmphasis" 8917.332942 ####
#     4.    "LargeAreaLowGrayLevelEmphasis" 4543.903833 ##
#     5.                      "ZoneEntropy" 3529.928272 #
#     6.         "LowGrayLevelZoneEmphasis" 3449.981583 #
#     7.  "SizeZoneNonUniformityNormalized" 2380.545021 #
#     8.    "SmallAreaLowGrayLevelEmphasis" 1442.705814
#     9.                     "ZoneVariance" 1384.100845
#    10.                "GrayLevelVariance" 1014.652996
#    11. "GrayLevelNonUniformityNormalized" 885.827232
#    12.   "SmallAreaHighGrayLevelEmphasis" 842.547123
#    13.                "SmallAreaEmphasis" 501.787207
#    14.            "SizeZoneNonUniformity" 354.649064
#    15.                   "ZonePercentage" 307.399502
#    16.                "LargeAreaEmphasis" 277.457602
#
#
#
# Loss: BINOMIAL_LOG_LIKELIHOOD
# Validation loss value: 0.594479
# Number of trees per iteration: 1
# Node format: NOT_SET
# Number of trees: 136
# Total number of nodes: 7364
#
# Number of nodes by tree:
# Count: 136 Average: 54.1471 StdDev: 7.56008
# Min: 33 Max: 63 Ignored: 0
# ----------------------------------------------
# [ 33, 34)  1   0.74%   0.74%
# [ 34, 36)  1   0.74%   1.47%
# [ 36, 37)  0   0.00%   1.47%
# [ 37, 39)  1   0.74%   2.21%
# [ 39, 40)  0   0.00%   2.21%
# [ 40, 42)  7   5.15%   7.35% ###
# [ 42, 43)  0   0.00%   7.35%
# [ 43, 45)  8   5.88%  13.24% ###
# [ 45, 46) 10   7.35%  20.59% ####
# [ 46, 48)  5   3.68%  24.26% ##
# [ 48, 50)  8   5.88%  30.15% ###
# [ 50, 51)  0   0.00%  30.15%
# [ 51, 53)  8   5.88%  36.03% ###
# [ 53, 54)  6   4.41%  40.44% ###
# [ 54, 56) 13   9.56%  50.00% #####
# [ 56, 57)  0   0.00%  50.00%
# [ 57, 59) 15  11.03%  61.03% ######
# [ 59, 60) 13   9.56%  70.59% #####
# [ 60, 62) 16  11.76%  82.35% #######
# [ 62, 63] 24  17.65% 100.00% ##########
#
# Depth by leafs:
# Count: 3750 Average: 4.884 StdDev: 0.424119
# Min: 2 Max: 5 Ignored: 0
# ----------------------------------------------
# [ 2, 3)   22   0.59%   0.59%
# [ 3, 4)   79   2.11%   2.69%
# [ 4, 5)  211   5.63%   8.32% #
# [ 5, 5] 3438  91.68% 100.00% ##########
#
# Number of training obs by leaf:
# Count: 3750 Average: 2569.13 StdDev: 8054.61
# Min: 5 Max: 67698 Ignored: 0
# ----------------------------------------------
# [     5,  3389) 3237  86.32%  86.32% ##########
# [  3389,  6774)  192   5.12%  91.44% #
# [  6774, 10159)   85   2.27%  93.71%
# [ 10159, 13543)   42   1.12%  94.83%
# [ 13543, 16928)   42   1.12%  95.95%
# [ 16928, 20313)   30   0.80%  96.75%
# [ 20313, 23697)   30   0.80%  97.55%
# [ 23697, 27082)    3   0.08%  97.63%
# [ 27082, 30467)   13   0.35%  97.97%
# [ 30467, 33852)    7   0.19%  98.16%
# [ 33852, 37236)   11   0.29%  98.45%
# [ 37236, 40621)    6   0.16%  98.61%
# [ 40621, 44006)    2   0.05%  98.67%
# [ 44006, 47390)    4   0.11%  98.77%
# [ 47390, 50775)    6   0.16%  98.93%
# [ 50775, 54160)    3   0.08%  99.01%
# [ 54160, 57544)   12   0.32%  99.33%
# [ 57544, 60929)    9   0.24%  99.57%
# [ 60929, 64314)    5   0.13%  99.71%
# [ 64314, 67698]   11   0.29% 100.00%
#
# Attribute in nodes:
# 	415 : LargeAreaHighGrayLevelEmphasis [NUMERICAL]
# 	396 : LargeAreaLowGrayLevelEmphasis [NUMERICAL]
# 	395 : GrayLevelNonUniformity [NUMERICAL]
# 	367 : HighGrayLevelZoneEmphasis [NUMERICAL]
# 	307 : LowGrayLevelZoneEmphasis [NUMERICAL]
# 	262 : ZoneEntropy [NUMERICAL]
# 	248 : ZoneVariance [NUMERICAL]
# 	213 : GrayLevelVariance [NUMERICAL]
# 	200 : SmallAreaHighGrayLevelEmphasis [NUMERICAL]
# 	181 : SmallAreaLowGrayLevelEmphasis [NUMERICAL]
# 	169 : GrayLevelNonUniformityNormalized [NUMERICAL]
# 	118 : SizeZoneNonUniformityNormalized [NUMERICAL]
# 	101 : SizeZoneNonUniformity [NUMERICAL]
# 	92 : LargeAreaEmphasis [NUMERICAL]
# 	83 : SmallAreaEmphasis [NUMERICAL]
# 	67 : ZonePercentage [NUMERICAL]
#
# Attribute in nodes with depth <= 0:
# 	51 : LargeAreaHighGrayLevelEmphasis [NUMERICAL]
# 	39 : HighGrayLevelZoneEmphasis [NUMERICAL]
# 	19 : GrayLevelNonUniformity [NUMERICAL]
# 	9 : LargeAreaLowGrayLevelEmphasis [NUMERICAL]
# 	7 : LowGrayLevelZoneEmphasis [NUMERICAL]
# 	4 : ZoneVariance [NUMERICAL]
# 	2 : SmallAreaLowGrayLevelEmphasis [NUMERICAL]
# 	2 : SmallAreaHighGrayLevelEmphasis [NUMERICAL]
# 	1 : SmallAreaEmphasis [NUMERICAL]
# 	1 : SizeZoneNonUniformityNormalized [NUMERICAL]
# 	1 : GrayLevelVariance [NUMERICAL]
#
# Attribute in nodes with depth <= 1:
# 	95 : LargeAreaHighGrayLevelEmphasis [NUMERICAL]
# 	71 : HighGrayLevelZoneEmphasis [NUMERICAL]
# 	59 : GrayLevelNonUniformity [NUMERICAL]
# 	50 : LargeAreaLowGrayLevelEmphasis [NUMERICAL]
# 	34 : ZoneVariance [NUMERICAL]
# 	21 : LowGrayLevelZoneEmphasis [NUMERICAL]
# 	17 : SizeZoneNonUniformityNormalized [NUMERICAL]
# 	13 : ZoneEntropy [NUMERICAL]
# 	10 : GrayLevelVariance [NUMERICAL]
# 	8 : GrayLevelNonUniformityNormalized [NUMERICAL]
# 	7 : LargeAreaEmphasis [NUMERICAL]
# 	6 : SmallAreaLowGrayLevelEmphasis [NUMERICAL]
# 	6 : SmallAreaHighGrayLevelEmphasis [NUMERICAL]
# 	6 : SmallAreaEmphasis [NUMERICAL]
# 	3 : SizeZoneNonUniformity [NUMERICAL]
# 	2 : ZonePercentage [NUMERICAL]
#
# Attribute in nodes with depth <= 2:
# 	133 : LargeAreaHighGrayLevelEmphasis [NUMERICAL]
# 	124 : LargeAreaLowGrayLevelEmphasis [NUMERICAL]
# 	117 : HighGrayLevelZoneEmphasis [NUMERICAL]
# 	114 : GrayLevelNonUniformity [NUMERICAL]
# 	82 : ZoneVariance [NUMERICAL]
# 	70 : LowGrayLevelZoneEmphasis [NUMERICAL]
# 	56 : GrayLevelVariance [NUMERICAL]
# 	50 : ZoneEntropy [NUMERICAL]
# 	35 : SmallAreaHighGrayLevelEmphasis [NUMERICAL]
# 	29 : SizeZoneNonUniformityNormalized [NUMERICAL]
# 	27 : LargeAreaEmphasis [NUMERICAL]
# 	24 : GrayLevelNonUniformityNormalized [NUMERICAL]
# 	21 : SmallAreaEmphasis [NUMERICAL]
# 	20 : SmallAreaLowGrayLevelEmphasis [NUMERICAL]
# 	18 : ZonePercentage [NUMERICAL]
# 	10 : SizeZoneNonUniformity [NUMERICAL]
#
# Attribute in nodes with depth <= 3:
# 	244 : LargeAreaLowGrayLevelEmphasis [NUMERICAL]
# 	231 : LargeAreaHighGrayLevelEmphasis [NUMERICAL]
# 	207 : GrayLevelNonUniformity [NUMERICAL]
# 	194 : HighGrayLevelZoneEmphasis [NUMERICAL]
# 	160 : LowGrayLevelZoneEmphasis [NUMERICAL]
# 	130 : ZoneVariance [NUMERICAL]
# 	123 : ZoneEntropy [NUMERICAL]
# 	123 : GrayLevelVariance [NUMERICAL]
# 	89 : SmallAreaHighGrayLevelEmphasis [NUMERICAL]
# 	85 : SmallAreaLowGrayLevelEmphasis [NUMERICAL]
# 	75 : GrayLevelNonUniformityNormalized [NUMERICAL]
# 	58 : SizeZoneNonUniformityNormalized [NUMERICAL]
# 	50 : SmallAreaEmphasis [NUMERICAL]
# 	47 : LargeAreaEmphasis [NUMERICAL]
# 	44 : SizeZoneNonUniformity [NUMERICAL]
# 	35 : ZonePercentage [NUMERICAL]
#
# Attribute in nodes with depth <= 5:
# 	415 : LargeAreaHighGrayLevelEmphasis [NUMERICAL]
# 	396 : LargeAreaLowGrayLevelEmphasis [NUMERICAL]
# 	395 : GrayLevelNonUniformity [NUMERICAL]
# 	367 : HighGrayLevelZoneEmphasis [NUMERICAL]
# 	307 : LowGrayLevelZoneEmphasis [NUMERICAL]
# 	262 : ZoneEntropy [NUMERICAL]
# 	248 : ZoneVariance [NUMERICAL]
# 	213 : GrayLevelVariance [NUMERICAL]
# 	200 : SmallAreaHighGrayLevelEmphasis [NUMERICAL]
# 	181 : SmallAreaLowGrayLevelEmphasis [NUMERICAL]
# 	169 : GrayLevelNonUniformityNormalized [NUMERICAL]
# 	118 : SizeZoneNonUniformityNormalized [NUMERICAL]
# 	101 : SizeZoneNonUniformity [NUMERICAL]
# 	92 : LargeAreaEmphasis [NUMERICAL]
# 	83 : SmallAreaEmphasis [NUMERICAL]
# 	67 : ZonePercentage [NUMERICAL]
#
# Condition type in nodes:
# 	3614 : HigherCondition
# Condition type in nodes with depth <= 0:
# 	136 : HigherCondition
# Condition type in nodes with depth <= 1:
# 	408 : HigherCondition
# Condition type in nodes with depth <= 2:
# 	930 : HigherCondition
# Condition type in nodes with depth <= 3:
# 	1895 : HigherCondition
# Condition type in nodes with depth <= 5:
# 	3614 : HigherCondition
#
# Training logs:
# Number of iteration to final model: 136
# 	Iter:1 train-loss:1.284460 valid-loss:1.291083  train-accuracy:0.831082 valid-accuracy:0.807188
# 	Iter:2 train-loss:1.200269 valid-loss:1.212395  train-accuracy:0.833291 valid-accuracy:0.809998
# 	Iter:3 train-loss:1.128044 valid-loss:1.143044  train-accuracy:0.835685 valid-accuracy:0.810139
# 	Iter:4 train-loss:1.068889 valid-loss:1.087544  train-accuracy:0.847835 valid-accuracy:0.828525
# 	Iter:5 train-loss:1.013176 valid-loss:1.033517  train-accuracy:0.853797 valid-accuracy:0.833428
# 	Iter:6 train-loss:0.966913 valid-loss:0.989535  train-accuracy:0.852550 valid-accuracy:0.836069
# 	Iter:16 train-loss:0.705549 valid-loss:0.746885  train-accuracy:0.869587 valid-accuracy:0.856720
# 	Iter:26 train-loss:0.616310 valid-loss:0.674635  train-accuracy:0.876291 valid-accuracy:0.858969
# 	Iter:36 train-loss:0.571052 valid-loss:0.644098  train-accuracy:0.881599 valid-accuracy:0.857473
# 	Iter:46 train-loss:0.544027 valid-loss:0.629865  train-accuracy:0.888262 valid-accuracy:0.862390
# 	Iter:56 train-loss:0.524253 valid-loss:0.620421  train-accuracy:0.891429 valid-accuracy:0.864512
# 	Iter:66 train-loss:0.504305 valid-loss:0.609527  train-accuracy:0.895924 valid-accuracy:0.866017
# 	Iter:76 train-loss:0.490194 valid-loss:0.605164  train-accuracy:0.899639 valid-accuracy:0.866500
# 	Iter:86 train-loss:0.475972 valid-loss:0.600392  train-accuracy:0.902595 valid-accuracy:0.868070
# 	Iter:96 train-loss:0.464178 valid-loss:0.599756  train-accuracy:0.905624 valid-accuracy:0.868147
# 	Iter:106 train-loss:0.452689 valid-loss:0.597002  train-accuracy:0.909759 valid-accuracy:0.868763
# 	Iter:116 train-loss:0.441792 valid-loss:0.595000  train-accuracy:0.913913 valid-accuracy:0.870880
# 	Iter:126 train-loss:0.432375 valid-loss:0.595915  train-accuracy:0.915815 valid-accuracy:0.872654
# 	Iter:136 train-loss:0.423553 valid-loss:0.594479  train-accuracy:0.917180 valid-accuracy:0.873065
# 	Iter:146 train-loss:0.416547 valid-loss:0.595284  train-accuracy:0.919976 valid-accuracy:0.870209
# 	Iter:156 train-loss:0.407634 valid-loss:0.597166  train-accuracy:0.922532 valid-accuracy:0.870761
# 	Iter:166 train-loss:0.398484 valid-loss:0.599358  train-accuracy:0.925389 valid-accuracy:0.868859

# %%
# Model features
model.make_inspector().features()
# Out:
# ["GrayLevelNonUniformity" (1; #0),
#  "GrayLevelNonUniformityNormalized" (1; #1),
#  "GrayLevelVariance" (1; #2),
#  "HighGrayLevelZoneEmphasis" (1; #3),
#  "LargeAreaEmphasis" (1; #4),
#  "LargeAreaHighGrayLevelEmphasis" (1; #5),
#  "LargeAreaLowGrayLevelEmphasis" (1; #6),
#  "LowGrayLevelZoneEmphasis" (1; #7),
#  "SizeZoneNonUniformity" (1; #8),
#  "SizeZoneNonUniformityNormalized" (1; #9),
#  "SmallAreaEmphasis" (1; #10),
#  "SmallAreaHighGrayLevelEmphasis" (1; #11),
#  "SmallAreaLowGrayLevelEmphasis" (1; #12),
#  "ZoneEntropy" (1; #13),
#  "ZonePercentage" (1; #14),
#  "ZoneVariance" (1; #15)]

# %%
# Feature importance
model.make_inspector().variable_importances()
# Out:
# {'INV_MEAN_MIN_DEPTH': [("LargeAreaHighGrayLevelEmphasis" (1; #5),
#    0.2891690175059157),
#   ("HighGrayLevelZoneEmphasis" (1; #3), 0.2500275714131135),
#   ("GrayLevelNonUniformity" (1; #0), 0.23326618822932238),
#   ("LargeAreaLowGrayLevelEmphasis" (1; #6), 0.21964136263955594),
#   ("ZoneVariance" (1; #15), 0.2024687314312236),
#   ("LowGrayLevelZoneEmphasis" (1; #7), 0.2000312011454603),
#   ("ZoneEntropy" (1; #13), 0.18815830377635653),
#   ("GrayLevelVariance" (1; #2), 0.18794359287854376),
#   ("SizeZoneNonUniformityNormalized" (1; #9), 0.18301711258524184),
#   ("SmallAreaHighGrayLevelEmphasis" (1; #11), 0.18274598380495505),
#   ("SmallAreaLowGrayLevelEmphasis" (1; #12), 0.18113779035805616),
#   ("GrayLevelNonUniformityNormalized" (1; #1), 0.18089460091557744),
#   ("LargeAreaEmphasis" (1; #4), 0.1778773286324432),
#   ("SmallAreaEmphasis" (1; #10), 0.17682502415695805),
#   ("ZonePercentage" (1; #14), 0.1758699946954767),
#   ("SizeZoneNonUniformity" (1; #8), 0.17558270265135542)],
#  'NUM_AS_ROOT': [("LargeAreaHighGrayLevelEmphasis" (1; #5), 51.0),
#   ("HighGrayLevelZoneEmphasis" (1; #3), 39.0),
#   ("GrayLevelNonUniformity" (1; #0), 19.0),
#   ("LargeAreaLowGrayLevelEmphasis" (1; #6), 9.0),
#   ("LowGrayLevelZoneEmphasis" (1; #7), 7.0),
#   ("ZoneVariance" (1; #15), 4.0),
#   ("SmallAreaHighGrayLevelEmphasis" (1; #11), 2.0),
#   ("SmallAreaLowGrayLevelEmphasis" (1; #12), 2.0),
#   ("GrayLevelVariance" (1; #2), 1.0),
#   ("SizeZoneNonUniformityNormalized" (1; #9), 1.0),
#   ("SmallAreaEmphasis" (1; #10), 1.0)],
#  'SUM_SCORE': [("HighGrayLevelZoneEmphasis" (1; #3), 31279.25752457635),
#   ("GrayLevelNonUniformity" (1; #0), 9389.06616088845),
#   ("LargeAreaHighGrayLevelEmphasis" (1; #5), 8917.33294240627),
#   ("LargeAreaLowGrayLevelEmphasis" (1; #6), 4543.903832926285),
#   ("ZoneEntropy" (1; #13), 3529.9282722108464),
#   ("LowGrayLevelZoneEmphasis" (1; #7), 3449.981583344631),
#   ("SizeZoneNonUniformityNormalized" (1; #9), 2380.545020930157),
#   ("SmallAreaLowGrayLevelEmphasis" (1; #12), 1442.7058141287037),
#   ("ZoneVariance" (1; #15), 1384.1008450125212),
#   ("GrayLevelVariance" (1; #2), 1014.6529964461229),
#   ("GrayLevelNonUniformityNormalized" (1; #1), 885.8272322093048),
#   ("SmallAreaHighGrayLevelEmphasis" (1; #11), 842.5471227982556),
#   ("SmallAreaEmphasis" (1; #10), 501.7872073672458),
#   ("SizeZoneNonUniformity" (1; #8), 354.649064196071),
#   ("ZonePercentage" (1; #14), 307.39950178879167),
#   ("LargeAreaEmphasis" (1; #4), 277.4576018618809)],
#  'NUM_NODES': [("LargeAreaHighGrayLevelEmphasis" (1; #5), 415.0),
#   ("LargeAreaLowGrayLevelEmphasis" (1; #6), 396.0),
#   ("GrayLevelNonUniformity" (1; #0), 395.0),
#   ("HighGrayLevelZoneEmphasis" (1; #3), 367.0),
#   ("LowGrayLevelZoneEmphasis" (1; #7), 307.0),
#   ("ZoneEntropy" (1; #13), 262.0),
#   ("ZoneVariance" (1; #15), 248.0),
#   ("GrayLevelVariance" (1; #2), 213.0),
#   ("SmallAreaHighGrayLevelEmphasis" (1; #11), 200.0),
#   ("SmallAreaLowGrayLevelEmphasis" (1; #12), 181.0),
#   ("GrayLevelNonUniformityNormalized" (1; #1), 169.0),
#   ("SizeZoneNonUniformityNormalized" (1; #9), 118.0),
#   ("SizeZoneNonUniformity" (1; #8), 101.0),
#   ("LargeAreaEmphasis" (1; #4), 92.0),
#   ("SmallAreaEmphasis" (1; #10), 83.0),
#   ("ZonePercentage" (1; #14), 67.0)]}

# %%
# Model self evaluation
model.make_inspector().evaluation()
# Out:
# Evaluation(num_examples=None, accuracy=0.8730646967887878, loss=0.5944793224334717, rmse=None, ndcg=None, aucs=None, auuc=None, qini=None)

# %%
logs = model.make_inspector().training_logs()

plt.figure(figsize=(12, 4))
plt.subplot(1, 2, 1)
plt.plot([log.num_trees for log in logs], [log.evaluation.accuracy for log in logs])
plt.xlabel("Number of trees")
plt.ylabel("Accuracy (out-of-bag)")
plt.subplot(1, 2, 2)
plt.plot([log.num_trees for log in logs], [log.evaluation.loss for log in logs])
plt.xlabel("Number of trees")
plt.ylabel("Logloss (out-of-bag)")
plt.show()

# %% [markdown]
# Calculate the score of our hold-out validation dataset

# %%
predictions = model.predict(val_ds)
y_true      = validation_data["label"]

from sklearn.metrics import roc_auc_score
ROC_AUC = roc_auc_score(y_true, predictions)
print("The ROC AUC score is %.5f" % ROC_AUC )
# Out:
#  1/12 [=>............................] - ETA: 0s
# 12/12 [==============================] - 0s 4ms/step
# The ROC AUC score is 0.95188

# %%
# Compute binary classification metrics with sklearn
import numpy as np
from sklearn.metrics import (
    accuracy_score,
    precision_score,
    recall_score,
    f1_score,
    roc_auc_score,
    average_precision_score,
    confusion_matrix,
    classification_report,
    matthews_corrcoef,
    log_loss,
    brier_score_loss,
)

# Get predictions (probabilities or class labels)
preds = model.predict(test_ds)
# If model outputs probabilities, convert to labels by threshold 0.5
if preds.ndim == 2:
    # For TFDF classification, preds may be class probabilities with shape (N, 2)
    if preds.shape[1] == 2:
        pos_probs = preds[:, 1]
    else:
        # If single-probability column (positive class)
        pos_probs = preds[:, -1]
    y_pred = (pos_probs >= 0.5).astype(int)
else:
    # Already class labels
    y_pred = preds.astype(int)
    pos_probs = None

# Ground truth labels (must be 0/1 integers)
y_true = test_data["label"].astype(int).to_numpy()

# Core metrics
metrics = {}
metrics["accuracy"] = accuracy_score(y_true, y_pred)
metrics["precision"] = precision_score(y_true, y_pred, zero_division=0)
metrics["recall"] = recall_score(y_true, y_pred, zero_division=0)
metrics["f1"] = f1_score(y_true, y_pred, zero_division=0)
metrics["mcc"] = matthews_corrcoef(y_true, y_pred)

# Probabilistic metrics (only if we have probabilities)
if pos_probs is not None:
    metrics["roc_auc"] = roc_auc_score(y_true, pos_probs)
    metrics["pr_auc"] = average_precision_score(y_true, pos_probs)
    metrics["log_loss"] = log_loss(y_true, pos_probs, labels=[0,1])
    metrics["brier_score"] = brier_score_loss(y_true, pos_probs)

# Confusion matrix and detailed report
cm = confusion_matrix(y_true, y_pred, labels=[0,1])
report = classification_report(y_true, y_pred, digits=4)

print("Sklearn binary metrics:")
for k, v in metrics.items():
    print(f"{k}: {v:.4f}")
print("\nConfusion matrix:\n", cm)
print("\nClassification report:\n", report)
# Out:
#  1/23 [>.............................] - ETA: 1s
# 14/23 [=================>............] - ETA: 0s
# 19/23 [=======================>......] - ETA: 0s
# 23/23 [==============================] - 1s 34ms/step
# Sklearn binary metrics:
# accuracy: 0.8997
# precision: 0.4110
# recall: 0.8364
# f1: 0.5511
# mcc: 0.5423
# roc_auc: 0.9495
# pr_auc: 0.7579
# log_loss: 0.2405
# brier_score: 0.0722
#
# Confusion matrix:
#  [[18849  1985]
#  [  271  1385]]
#
# Classification report:
#                precision    recall  f1-score   support
#
#            0     0.9858    0.9047    0.9435     20834
#            1     0.4110    0.8364    0.5511      1656
#
#     accuracy                         0.8997     22490
#    macro avg     0.6984    0.8705    0.7473     22490
# weighted avg     0.9435    0.8997    0.9146     22490
