# %%
# Import packages and modules
import numpy  as np
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow_decision_forests as tfdf

from sklearn.model_selection import train_test_split
# Out:
# 2026-07-04 07:35:49.425929: I tensorflow/core/util/port.cc:113] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2026-07-04 07:35:49.472969: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2026-07-04 07:35:53.852158: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
# Check the version of TensorFlow Decision Forests
print("Found TensorFlow Decision Forests v" + tfdf.__version__)
# Out:
# Found TensorFlow Decision Forests v1.9.1

# %%
datasetPath = 'dataset/firstorder/kernel5-radius5/dataset.csv'

# %%
# Parameters
datasetPath = "dataset/firstorder/kernel5-radius5/200.dataset.csv"

# %%
# train/validation/test = 70/10/20
dataset = pd.read_csv(datasetPath)

train_data, temp_data = train_test_split(dataset, test_size=0.3, random_state=42)
validation_data, test_data = train_test_split(temp_data, test_size=2/3, random_state=42)

# %%
from sklearn.utils.class_weight import compute_class_weight

# tinh class weight tren tap train
classes = np.array([0, 1])
weights = compute_class_weight(class_weight="balanced", classes=classes, y=train_data["label"])
class_weight = {0: weights[0], 1: weights[1]}

# gan sample_weight cho tung dong
train_data["sample_weight"] = train_data["label"].map(class_weight)
validation_data["sample_weight"] = validation_data["label"].map(class_weight)
test_data["sample_weight"] = test_data["label"].map(class_weight)

# Convert the dataset into a TensorFlow dataset.
train_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    train_data, label="label", weight="sample_weight"
)         
val_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    validation_data, label="label", weight="sample_weight"
)
test_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    test_data, label="label", weight="sample_weight"
)
# Out:
# 2026-07-04 07:36:06.130021: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:984] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2026-07-04 07:36:06.131603: W tensorflow/core/common_runtime/gpu/gpu_device.cc:2251] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...

# %%
import keras

# %%
# %%time

# Train a Gradient Boosted Trees model.
model = tfdf.keras.GradientBoostedTreesModel()

# Add evaluation metrics
model.compile(
    metrics=["accuracy"]
)
model.fit(x=train_ds)

# # Train a Gradient Boosted Trees model.
# model = tfdf.keras.GradientBoostedTreesModel(num_trees=1500)
# model.fit(train_ds)
# Out:
# Use /tmp/tmp5om95izf as temporary training directory
# Reading training dataset...
# [WARNING 26-07-04 07:36:06.2784 UTC gradient_boosted_trees.cc:1840] "goss_alpha" set but "sampling_method" not equal to "GOSS".
# [WARNING 26-07-04 07:36:06.2784 UTC gradient_boosted_trees.cc:1851] "goss_beta" set but "sampling_method" not equal to "GOSS".
# [WARNING 26-07-04 07:36:06.2784 UTC gradient_boosted_trees.cc:1865] "selective_gradient_boosting_ratio" set but "sampling_method" not equal to "SELGB".
# Training dataset read in 0:00:03.249170. Found 157360 examples.
# Training model...
# Model trained in 0:00:33.735142
# Compiling model...
# [INFO 26-07-04 07:36:43.2725 UTC kernel.cc:1233] Loading model from path /tmp/tmp5om95izf/model/ with prefix 29bd179fc7a44db1
# [INFO 26-07-04 07:36:43.2841 UTC quick_scorer_extended.cc:911] The binary was compiled without AVX2 support, but your CPU supports it. Enable it for faster model inference.
# [INFO 26-07-04 07:36:43.2849 UTC abstract_model.cc:1362] Engine "GradientBoostedTreesQuickScorerExtended" built
# [INFO 26-07-04 07:36:43.2849 UTC kernel.cc:1061] Use fast generic engine
# Model compiled.
# CPU times: user 4min 2s, sys: 3.22 s, total: 4min 6s
# Wall time: 37.7 s

# %%
# Evaluate the model
evaluate = model.evaluate(val_ds, return_dict=True)
print()

for name, value in evaluate.items():
    print(f"{name}: {value:.4f}")
# Out:
# WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
#  1/23 [>.............................] - ETA: 1:47 - loss: 0.0000e+00 - accuracy: 0.8680
# 11/23 [=============>................] - ETA: 0s - loss: 0.0000e+00 - accuracy: 0.8843
# 23/23 [==============================] - ETA: 0s - loss: 0.0000e+00 - accuracy: 0.8821
# 23/23 [==============================] - 5s 5ms/step - loss: 0.0000e+00 - accuracy: 0.8821
# loss: 0.0000
# accuracy: 0.8821

# %%
# Model Summary
model.summary()
# Out:
# Model: "gradient_boosted_trees_model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
# =================================================================
# Total params: 1 (1.00 Byte)
# Trainable params: 0 (0.00 Byte)
# Non-trainable params: 1 (1.00 Byte)
# _________________________________________________________________
# Type: "GRADIENT_BOOSTED_TREES"
# Task: CLASSIFICATION
# Label: "__LABEL"
#
# Input Features (18):
# 	10Percentile
# 	90Percentile
# 	Energy
# 	Entropy
# 	InterquartileRange
# 	Kurtosis
# 	Maximum
# 	Mean
# 	MeanAbsoluteDeviation
# 	Median
# 	Minimum
# 	Range
# 	RobustMeanAbsoluteDeviation
# 	RootMeanSquared
# 	Skewness
# 	TotalEnergy
# 	Uniformity
# 	Variance
#
# Trained with weights
#
# Variable Importance: INV_MEAN_MIN_DEPTH:
#     1.                    "Skewness"  0.217444 ################
#     2.                "10Percentile"  0.211311 #############
#     3.                     "Minimum"  0.209186 ############
#     4.                    "Kurtosis"  0.208442 ############
#     5.                "90Percentile"  0.205473 ###########
#     6.                      "Median"  0.198619 ########
#     7.                     "Maximum"  0.198585 ########
#     8.                    "Variance"  0.193876 #######
#     9.                  "Uniformity"  0.192227 ######
#    10. "RobustMeanAbsoluteDeviation"  0.189835 #####
#    11.                       "Range"  0.189692 #####
#    12.                        "Mean"  0.189510 #####
#    13.                     "Entropy"  0.184838 ###
#    14.       "MeanAbsoluteDeviation"  0.180046 #
#    15.          "InterquartileRange"  0.178859 #
#    16.                      "Energy"  0.175357
#    17.             "RootMeanSquared"  0.175295
#    18.                 "TotalEnergy"  0.174926
#
# Variable Importance: NUM_AS_ROOT:
#     1.                    "Skewness" 31.000000 ################
#     2.                "10Percentile" 28.000000 ##############
#     3.                    "Kurtosis" 27.000000 #############
#     4.                    "Variance" 23.000000 ###########
#     5.                     "Minimum" 22.000000 ###########
#     6.                "90Percentile" 21.000000 ##########
#     7.                        "Mean" 15.000000 #######
#     8.                      "Median" 15.000000 #######
#     9. "RobustMeanAbsoluteDeviation" 14.000000 ######
#    10.                  "Uniformity" 10.000000 ####
#    11.       "MeanAbsoluteDeviation"  6.000000 ##
#    12.                     "Entropy"  4.000000 #
#    13.                     "Maximum"  4.000000 #
#    14.                       "Range"  2.000000
#    15.                      "Energy"  1.000000
#    16.          "InterquartileRange"  1.000000
#    17.             "RootMeanSquared"  1.000000
#
# Variable Importance: NUM_NODES:
#     1.                    "Skewness" 639.000000 ################
#     2.                    "Kurtosis" 514.000000 ############
#     3.                     "Maximum" 489.000000 ###########
#     4.                     "Minimum" 487.000000 ###########
#     5.                "90Percentile" 486.000000 ###########
#     6.                      "Median" 420.000000 #########
#     7.                "10Percentile" 400.000000 ########
#     8.                       "Range" 373.000000 ########
#     9.                  "Uniformity" 351.000000 #######
#    10.                    "Variance" 296.000000 #####
#    11.                     "Entropy" 295.000000 #####
#    12. "RobustMeanAbsoluteDeviation" 277.000000 #####
#    13.                        "Mean" 264.000000 #####
#    14.          "InterquartileRange" 226.000000 ###
#    15.       "MeanAbsoluteDeviation" 179.000000 ##
#    16.             "RootMeanSquared" 118.000000
#    17.                      "Energy" 110.000000
#    18.                 "TotalEnergy" 93.000000
#
# Variable Importance: SUM_SCORE:
#     1.                        "Mean" 29622.577080 ################
#     2.                "90Percentile" 25792.079279 #############
#     3.                     "Maximum" 13374.246826 ######
#     4.                "10Percentile" 10744.879141 #####
#     5.                     "Minimum" 8241.516308 ####
#     6.                    "Kurtosis" 6548.337620 ###
#     7.                      "Energy" 5253.321317 ##
#     8.                    "Skewness" 3764.591148 #
#     9.             "RootMeanSquared" 3528.862543 #
#    10.                      "Median" 3231.947089 #
#    11.          "InterquartileRange" 3115.329631 #
#    12.                  "Uniformity" 2723.471911
#    13.                       "Range" 2617.892219
#    14.                 "TotalEnergy" 2262.148496
#    15.                    "Variance" 2081.469130
#    16. "RobustMeanAbsoluteDeviation" 2045.712033
#    17.                     "Entropy" 1327.156740
#    18.       "MeanAbsoluteDeviation" 1045.541557
#
#
#
# Loss: BINOMIAL_LOG_LIKELIHOOD
# Validation loss value: 0.671002
# Number of trees per iteration: 1
# Node format: NOT_SET
# Number of trees: 225
# Total number of nodes: 12259
#
# Number of nodes by tree:
# Count: 225 Average: 54.4844 StdDev: 8.13776
# Min: 27 Max: 63 Ignored: 0
# ----------------------------------------------
# [ 27, 28)  2   0.89%   0.89%
# [ 28, 30)  3   1.33%   2.22% #
# [ 30, 32)  1   0.44%   2.67%
# [ 32, 34)  0   0.00%   2.67%
# [ 34, 36)  2   0.89%   3.56%
# [ 36, 38)  1   0.44%   4.00%
# [ 38, 39)  0   0.00%   4.00%
# [ 39, 41)  3   1.33%   5.33% #
# [ 41, 43)  7   3.11%   8.44% #
# [ 43, 45)  3   1.33%   9.78% #
# [ 45, 47) 13   5.78%  15.56% ###
# [ 47, 49)  9   4.00%  19.56% ##
# [ 49, 51) 13   5.78%  25.33% ###
# [ 51, 52) 17   7.56%  32.89% ####
# [ 52, 54) 17   7.56%  40.44% ####
# [ 54, 56) 19   8.44%  48.89% ####
# [ 56, 58) 19   8.44%  57.33% ####
# [ 58, 60) 22   9.78%  67.11% #####
# [ 60, 62) 27  12.00%  79.11% ######
# [ 62, 63] 47  20.89% 100.00% ##########
#
# Depth by leafs:
# Count: 6242 Average: 4.88946 StdDev: 0.41706
# Min: 2 Max: 5 Ignored: 0
# ----------------------------------------------
# [ 2, 3)   32   0.51%   0.51%
# [ 3, 4)  140   2.24%   2.76%
# [ 4, 5)  314   5.03%   7.79% #
# [ 5, 5] 5756  92.21% 100.00% ##########
#
# Number of training obs by leaf:
# Count: 6242 Average: 5106.51 StdDev: 17053.9
# Min: 5 Max: 141204 Ignored: 0
# ----------------------------------------------
# [      5,   7065) 5422  86.86%  86.86% ##########
# [   7065,  14125)  323   5.17%  92.04% #
# [  14125,  21185)  120   1.92%  93.96%
# [  21185,  28245)  100   1.60%  95.56%
# [  28245,  35305)   35   0.56%  96.12%
# [  35305,  42365)   30   0.48%  96.60%
# [  42365,  49425)   30   0.48%  97.08%
# [  49425,  56485)   22   0.35%  97.44%
# [  56485,  63545)   18   0.29%  97.73%
# [  63545,  70605)   18   0.29%  98.01%
# [  70605,  77665)   14   0.22%  98.24%
# [  77665,  84725)   10   0.16%  98.40%
# [  84725,  91785)   13   0.21%  98.61%
# [  91785,  98845)   18   0.29%  98.89%
# [  98845, 105905)   11   0.18%  99.07%
# [ 105905, 112965)    9   0.14%  99.21%
# [ 112965, 120025)    4   0.06%  99.28%
# [ 120025, 127085)    9   0.14%  99.42%
# [ 127085, 134145)   15   0.24%  99.66%
# [ 134145, 141204]   21   0.34% 100.00%
#
# Attribute in nodes:
# 	639 : Skewness [NUMERICAL]
# 	514 : Kurtosis [NUMERICAL]
# 	489 : Maximum [NUMERICAL]
# 	487 : Minimum [NUMERICAL]
# 	486 : 90Percentile [NUMERICAL]
# 	420 : Median [NUMERICAL]
# 	400 : 10Percentile [NUMERICAL]
# 	373 : Range [NUMERICAL]
# 	351 : Uniformity [NUMERICAL]
# 	296 : Variance [NUMERICAL]
# 	295 : Entropy [NUMERICAL]
# 	277 : RobustMeanAbsoluteDeviation [NUMERICAL]
# 	264 : Mean [NUMERICAL]
# 	226 : InterquartileRange [NUMERICAL]
# 	179 : MeanAbsoluteDeviation [NUMERICAL]
# 	118 : RootMeanSquared [NUMERICAL]
# 	110 : Energy [NUMERICAL]
# 	93 : TotalEnergy [NUMERICAL]
#
# Attribute in nodes with depth <= 0:
# 	31 : Skewness [NUMERICAL]
# 	28 : 10Percentile [NUMERICAL]
# 	27 : Kurtosis [NUMERICAL]
# 	23 : Variance [NUMERICAL]
# 	22 : Minimum [NUMERICAL]
# 	21 : 90Percentile [NUMERICAL]
# 	15 : Median [NUMERICAL]
# 	15 : Mean [NUMERICAL]
# 	14 : RobustMeanAbsoluteDeviation [NUMERICAL]
# 	10 : Uniformity [NUMERICAL]
# 	6 : MeanAbsoluteDeviation [NUMERICAL]
# 	4 : Maximum [NUMERICAL]
# 	4 : Entropy [NUMERICAL]
# 	2 : Range [NUMERICAL]
# 	1 : RootMeanSquared [NUMERICAL]
# 	1 : InterquartileRange [NUMERICAL]
# 	1 : Energy [NUMERICAL]
#
# Attribute in nodes with depth <= 1:
# 	95 : Kurtosis [NUMERICAL]
# 	88 : Skewness [NUMERICAL]
# 	62 : 10Percentile [NUMERICAL]
# 	50 : 90Percentile [NUMERICAL]
# 	46 : Maximum [NUMERICAL]
# 	44 : Variance [NUMERICAL]
# 	44 : Minimum [NUMERICAL]
# 	40 : Mean [NUMERICAL]
# 	35 : Uniformity [NUMERICAL]
# 	32 : Median [NUMERICAL]
# 	31 : Range [NUMERICAL]
# 	28 : RobustMeanAbsoluteDeviation [NUMERICAL]
# 	22 : Entropy [NUMERICAL]
# 	20 : MeanAbsoluteDeviation [NUMERICAL]
# 	12 : InterquartileRange [NUMERICAL]
# 	10 : TotalEnergy [NUMERICAL]
# 	8 : RootMeanSquared [NUMERICAL]
# 	8 : Energy [NUMERICAL]
#
# Attribute in nodes with depth <= 2:
# 	182 : Skewness [NUMERICAL]
# 	172 : Kurtosis [NUMERICAL]
# 	129 : Minimum [NUMERICAL]
# 	124 : 90Percentile [NUMERICAL]
# 	119 : Maximum [NUMERICAL]
# 	111 : 10Percentile [NUMERICAL]
# 	98 : Median [NUMERICAL]
# 	92 : Uniformity [NUMERICAL]
# 	86 : Variance [NUMERICAL]
# 	83 : Mean [NUMERICAL]
# 	76 : Range [NUMERICAL]
# 	70 : RobustMeanAbsoluteDeviation [NUMERICAL]
# 	62 : Entropy [NUMERICAL]
# 	46 : MeanAbsoluteDeviation [NUMERICAL]
# 	28 : InterquartileRange [NUMERICAL]
# 	24 : RootMeanSquared [NUMERICAL]
# 	22 : Energy [NUMERICAL]
# 	19 : TotalEnergy [NUMERICAL]
#
# Attribute in nodes with depth <= 3:
# 	347 : Skewness [NUMERICAL]
# 	288 : Kurtosis [NUMERICAL]
# 	266 : Maximum [NUMERICAL]
# 	265 : 90Percentile [NUMERICAL]
# 	259 : Minimum [NUMERICAL]
# 	229 : Median [NUMERICAL]
# 	209 : 10Percentile [NUMERICAL]
# 	184 : Uniformity [NUMERICAL]
# 	168 : Range [NUMERICAL]
# 	165 : Variance [NUMERICAL]
# 	150 : Mean [NUMERICAL]
# 	146 : RobustMeanAbsoluteDeviation [NUMERICAL]
# 	144 : Entropy [NUMERICAL]
# 	91 : InterquartileRange [NUMERICAL]
# 	83 : MeanAbsoluteDeviation [NUMERICAL]
# 	52 : RootMeanSquared [NUMERICAL]
# 	51 : Energy [NUMERICAL]
# 	42 : TotalEnergy [NUMERICAL]
#
# Attribute in nodes with depth <= 5:
# 	639 : Skewness [NUMERICAL]
# 	514 : Kurtosis [NUMERICAL]
# 	489 : Maximum [NUMERICAL]
# 	487 : Minimum [NUMERICAL]
# 	486 : 90Percentile [NUMERICAL]
# 	420 : Median [NUMERICAL]
# 	400 : 10Percentile [NUMERICAL]
# 	373 : Range [NUMERICAL]
# 	351 : Uniformity [NUMERICAL]
# 	296 : Variance [NUMERICAL]
# 	295 : Entropy [NUMERICAL]
# 	277 : RobustMeanAbsoluteDeviation [NUMERICAL]
# 	264 : Mean [NUMERICAL]
# 	226 : InterquartileRange [NUMERICAL]
# 	179 : MeanAbsoluteDeviation [NUMERICAL]
# 	118 : RootMeanSquared [NUMERICAL]
# 	110 : Energy [NUMERICAL]
# 	93 : TotalEnergy [NUMERICAL]
#
# Condition type in nodes:
# 	6017 : HigherCondition
# Condition type in nodes with depth <= 0:
# 	225 : HigherCondition
# Condition type in nodes with depth <= 1:
# 	675 : HigherCondition
# Condition type in nodes with depth <= 2:
# 	1543 : HigherCondition
# Condition type in nodes with depth <= 3:
# 	3139 : HigherCondition
# Condition type in nodes with depth <= 5:
# 	6017 : HigherCondition
#
# Training logs:
# Number of iteration to final model: 225
# 	Iter:1 train-loss:1.296876 valid-loss:1.296981  train-accuracy:0.813235 valid-accuracy:0.814276
# 	Iter:2 train-loss:1.222496 valid-loss:1.223908  train-accuracy:0.817188 valid-accuracy:0.816390
# 	Iter:3 train-loss:1.158931 valid-loss:1.161230  train-accuracy:0.822188 valid-accuracy:0.819823
# 	Iter:4 train-loss:1.106400 valid-loss:1.109926  train-accuracy:0.824106 valid-accuracy:0.820064
# 	Iter:5 train-loss:1.058023 valid-loss:1.061749  train-accuracy:0.825789 valid-accuracy:0.820985
# 	Iter:6 train-loss:1.019398 valid-loss:1.023189  train-accuracy:0.827979 valid-accuracy:0.823832
# 	Iter:16 train-loss:0.804671 valid-loss:0.819318  train-accuracy:0.842894 valid-accuracy:0.835188
# 	Iter:26 train-loss:0.724656 valid-loss:0.745725  train-accuracy:0.850137 valid-accuracy:0.842950
# 	Iter:36 train-loss:0.688167 valid-loss:0.717131  train-accuracy:0.855172 valid-accuracy:0.845517
# 	Iter:46 train-loss:0.665335 valid-loss:0.704099  train-accuracy:0.857885 valid-accuracy:0.845758
# 	Iter:56 train-loss:0.649853 valid-loss:0.698037  train-accuracy:0.860978 valid-accuracy:0.846785
# 	Iter:66 train-loss:0.637465 valid-loss:0.691648  train-accuracy:0.863942 valid-accuracy:0.848084
# 	Iter:76 train-loss:0.627056 valid-loss:0.687046  train-accuracy:0.866835 valid-accuracy:0.847231
# 	Iter:86 train-loss:0.617753 valid-loss:0.684030  train-accuracy:0.868203 valid-accuracy:0.847984
# 	Iter:96 train-loss:0.610219 valid-loss:0.681423  train-accuracy:0.870291 valid-accuracy:0.849693
# 	Iter:106 train-loss:0.604593 valid-loss:0.681260  train-accuracy:0.872194 valid-accuracy:0.849147
# 	Iter:116 train-loss:0.596049 valid-loss:0.678512  train-accuracy:0.874484 valid-accuracy:0.849216
# 	Iter:126 train-loss:0.589450 valid-loss:0.676671  train-accuracy:0.875797 valid-accuracy:0.849575
# 	Iter:136 train-loss:0.583121 valid-loss:0.674819  train-accuracy:0.877493 valid-accuracy:0.850499
# 	Iter:146 train-loss:0.577564 valid-loss:0.673677  train-accuracy:0.879683 valid-accuracy:0.850500
# 	Iter:156 train-loss:0.570620 valid-loss:0.673091  train-accuracy:0.881528 valid-accuracy:0.850159
# 	Iter:166 train-loss:0.565268 valid-loss:0.673454  train-accuracy:0.883378 valid-accuracy:0.849886
# 	Iter:176 train-loss:0.559881 valid-loss:0.672942  train-accuracy:0.884993 valid-accuracy:0.849682
# 	Iter:186 train-loss:0.555448 valid-loss:0.673663  train-accuracy:0.886670 valid-accuracy:0.850690
# 	Iter:196 train-loss:0.548848 valid-loss:0.671642  train-accuracy:0.889506 valid-accuracy:0.851153
# 	Iter:206 train-loss:0.544176 valid-loss:0.671308  train-accuracy:0.890751 valid-accuracy:0.851632
# 	Iter:216 train-loss:0.540052 valid-loss:0.672018  train-accuracy:0.891560 valid-accuracy:0.851939
# 	Iter:226 train-loss:0.534604 valid-loss:0.671117  train-accuracy:0.893122 valid-accuracy:0.851804
# 	Iter:236 train-loss:0.530278 valid-loss:0.672017  train-accuracy:0.894298 valid-accuracy:0.851189
# 	Iter:246 train-loss:0.524637 valid-loss:0.671351  train-accuracy:0.896105 valid-accuracy:0.850779

# %%
# Model features
model.make_inspector().features()
# Out:
# ["10Percentile" (1; #0),
#  "90Percentile" (1; #1),
#  "Energy" (1; #2),
#  "Entropy" (1; #3),
#  "InterquartileRange" (1; #4),
#  "Kurtosis" (1; #5),
#  "Maximum" (1; #6),
#  "Mean" (1; #7),
#  "MeanAbsoluteDeviation" (1; #8),
#  "Median" (1; #9),
#  "Minimum" (1; #10),
#  "Range" (1; #11),
#  "RobustMeanAbsoluteDeviation" (1; #12),
#  "RootMeanSquared" (1; #13),
#  "Skewness" (1; #14),
#  "TotalEnergy" (1; #15),
#  "Uniformity" (1; #16),
#  "Variance" (1; #17)]

# %%
# Feature importance
model.make_inspector().variable_importances()
# Out:
# {'INV_MEAN_MIN_DEPTH': [("Skewness" (1; #14), 0.21744374127417204),
#   ("10Percentile" (1; #0), 0.21131097091304393),
#   ("Minimum" (1; #10), 0.2091857093404205),
#   ("Kurtosis" (1; #5), 0.20844234924070687),
#   ("90Percentile" (1; #1), 0.20547254429189735),
#   ("Median" (1; #9), 0.19861919684375176),
#   ("Maximum" (1; #6), 0.1985854314575219),
#   ("Variance" (1; #17), 0.19387564523726414),
#   ("Uniformity" (1; #16), 0.19222726510324914),
#   ("RobustMeanAbsoluteDeviation" (1; #12), 0.18983483540756152),
#   ("Range" (1; #11), 0.1896918557277032),
#   ("Mean" (1; #7), 0.18950994864488063),
#   ("Entropy" (1; #3), 0.1848381554490846),
#   ("MeanAbsoluteDeviation" (1; #8), 0.18004642761751694),
#   ("InterquartileRange" (1; #4), 0.17885944214745336),
#   ("Energy" (1; #2), 0.17535745149484558),
#   ("RootMeanSquared" (1; #13), 0.17529509336209112),
#   ("TotalEnergy" (1; #15), 0.17492582068374277)],
#  'SUM_SCORE': [("Mean" (1; #7), 29622.57708000938),
#   ("90Percentile" (1; #1), 25792.079278841626),
#   ("Maximum" (1; #6), 13374.246825670456),
#   ("10Percentile" (1; #0), 10744.87914087661),
#   ("Minimum" (1; #10), 8241.516308372837),
#   ("Kurtosis" (1; #5), 6548.337619894504),
#   ("Energy" (1; #2), 5253.32131745969),
#   ("Skewness" (1; #14), 3764.591148123588),
#   ("RootMeanSquared" (1; #13), 3528.862542510225),
#   ("Median" (1; #9), 3231.947088924633),
#   ("InterquartileRange" (1; #4), 3115.3296314499826),
#   ("Uniformity" (1; #16), 2723.471910672498),
#   ("Range" (1; #11), 2617.8922191167353),
#   ("TotalEnergy" (1; #15), 2262.148496342032),
#   ("Variance" (1; #17), 2081.4691300844106),
#   ("RobustMeanAbsoluteDeviation" (1; #12), 2045.7120325313062),
#   ("Entropy" (1; #3), 1327.1567400227207),
#   ("MeanAbsoluteDeviation" (1; #8), 1045.5415572789616)],
#  'NUM_AS_ROOT': [("Skewness" (1; #14), 31.0),
#   ("10Percentile" (1; #0), 28.0),
#   ("Kurtosis" (1; #5), 27.0),
#   ("Variance" (1; #17), 23.0),
#   ("Minimum" (1; #10), 22.0),
#   ("90Percentile" (1; #1), 21.0),
#   ("Mean" (1; #7), 15.0),
#   ("Median" (1; #9), 15.0),
#   ("RobustMeanAbsoluteDeviation" (1; #12), 14.0),
#   ("Uniformity" (1; #16), 10.0),
#   ("MeanAbsoluteDeviation" (1; #8), 6.0),
#   ("Entropy" (1; #3), 4.0),
#   ("Maximum" (1; #6), 4.0),
#   ("Range" (1; #11), 2.0),
#   ("Energy" (1; #2), 1.0),
#   ("InterquartileRange" (1; #4), 1.0),
#   ("RootMeanSquared" (1; #13), 1.0)],
#  'NUM_NODES': [("Skewness" (1; #14), 639.0),
#   ("Kurtosis" (1; #5), 514.0),
#   ("Maximum" (1; #6), 489.0),
#   ("Minimum" (1; #10), 487.0),
#   ("90Percentile" (1; #1), 486.0),
#   ("Median" (1; #9), 420.0),
#   ("10Percentile" (1; #0), 400.0),
#   ("Range" (1; #11), 373.0),
#   ("Uniformity" (1; #16), 351.0),
#   ("Variance" (1; #17), 296.0),
#   ("Entropy" (1; #3), 295.0),
#   ("RobustMeanAbsoluteDeviation" (1; #12), 277.0),
#   ("Mean" (1; #7), 264.0),
#   ("InterquartileRange" (1; #4), 226.0),
#   ("MeanAbsoluteDeviation" (1; #8), 179.0),
#   ("RootMeanSquared" (1; #13), 118.0),
#   ("Energy" (1; #2), 110.0),
#   ("TotalEnergy" (1; #15), 93.0)]}

# %%
# Model self evaluation
model.make_inspector().evaluation()
# Out:
# Evaluation(num_examples=None, accuracy=0.8518378734588623, loss=0.6710021495819092, rmse=None, ndcg=None, aucs=None, auuc=None, qini=None)

# %%
logs = model.make_inspector().training_logs()

plt.figure(figsize=(12, 4))
plt.subplot(1, 2, 1)
plt.plot([log.num_trees for log in logs], [log.evaluation.accuracy for log in logs])
plt.xlabel("Number of trees")
plt.ylabel("Accuracy (out-of-bag)")
plt.subplot(1, 2, 2)
plt.plot([log.num_trees for log in logs], [log.evaluation.loss for log in logs])
plt.xlabel("Number of trees")
plt.ylabel("Logloss (out-of-bag)")
plt.show()

# %% [markdown]
# Calculate the score of our hold-out validation dataset

# %%
predictions = model.predict(val_ds)
y_true      = validation_data["label"]

from sklearn.metrics import roc_auc_score
ROC_AUC = roc_auc_score(y_true, predictions)
print("The ROC AUC score is %.5f" % ROC_AUC )
# Out:
#  1/23 [>.............................] - ETA: 2s
# 12/23 [==============>...............] - ETA: 0s
# 23/23 [==============================] - 0s 5ms/step
# The ROC AUC score is 0.93442

# %%
# Compute binary classification metrics with sklearn
import numpy as np
from sklearn.metrics import (
    accuracy_score,
    precision_score,
    recall_score,
    f1_score,
    roc_auc_score,
    average_precision_score,
    confusion_matrix,
    classification_report,
    matthews_corrcoef,
    log_loss,
    brier_score_loss,
)

# Get predictions (probabilities or class labels)
preds = model.predict(test_ds)
# If model outputs probabilities, convert to labels by threshold 0.5
if preds.ndim == 2:
    # For TFDF classification, preds may be class probabilities with shape (N, 2)
    if preds.shape[1] == 2:
        pos_probs = preds[:, 1]
    else:
        # If single-probability column (positive class)
        pos_probs = preds[:, -1]
    y_pred = (pos_probs >= 0.5).astype(int)
else:
    # Already class labels
    y_pred = preds.astype(int)
    pos_probs = None

# Ground truth labels (must be 0/1 integers)
y_true = test_data["label"].astype(int).to_numpy()

# Core metrics
metrics = {}
metrics["accuracy"] = accuracy_score(y_true, y_pred)
metrics["precision"] = precision_score(y_true, y_pred, zero_division=0)
metrics["recall"] = recall_score(y_true, y_pred, zero_division=0)
metrics["f1"] = f1_score(y_true, y_pred, zero_division=0)
metrics["mcc"] = matthews_corrcoef(y_true, y_pred)

# Probabilistic metrics (only if we have probabilities)
if pos_probs is not None:
    metrics["roc_auc"] = roc_auc_score(y_true, pos_probs)
    metrics["pr_auc"] = average_precision_score(y_true, pos_probs)
    metrics["log_loss"] = log_loss(y_true, pos_probs, labels=[0,1])
    metrics["brier_score"] = brier_score_loss(y_true, pos_probs)

# Confusion matrix and detailed report
cm = confusion_matrix(y_true, y_pred, labels=[0,1])
report = classification_report(y_true, y_pred, digits=4)

print("Sklearn binary metrics:")
for k, v in metrics.items():
    print(f"{k}: {v:.4f}")
print("\nConfusion matrix:\n", cm)
print("\nClassification report:\n", report)
# Out:
#  1/45 [..............................] - ETA: 3s
# 12/45 [=======>......................] - ETA: 0s
# 24/45 [===============>..............] - ETA: 0s
# 34/45 [=====================>........] - ETA: 0s
# 45/45 [==============================] - 0s 5ms/step
# Sklearn binary metrics:
# accuracy: 0.8822
# precision: 0.3306
# recall: 0.8034
# f1: 0.4685
# mcc: 0.4670
# roc_auc: 0.9249
# pr_auc: 0.6354
# log_loss: 0.2938
# brier_score: 0.0886
#
# Confusion matrix:
#  [[37331  4725]
#  [  571  2334]]
#
# Classification report:
#                precision    recall  f1-score   support
#
#            0     0.9849    0.8876    0.9338     42056
#            1     0.3306    0.8034    0.4685      2905
#
#     accuracy                         0.8822     44961
#    macro avg     0.6578    0.8455    0.7011     44961
# weighted avg     0.9427    0.8822    0.9037     44961
