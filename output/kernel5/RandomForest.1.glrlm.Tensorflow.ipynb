# %%
# Import packages and modules
import numpy  as np
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow_decision_forests as tfdf

from sklearn.model_selection import train_test_split
# Out:
# 2026-08-15 05:18:05.184129: I tensorflow/core/util/port.cc:113] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2026-08-15 05:18:05.542424: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2026-08-15 05:18:11.123029: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
# Check the version of TensorFlow Decision Forests
print("Found TensorFlow Decision Forests v" + tfdf.__version__)
# Out:
# Found TensorFlow Decision Forests v1.9.1

# %%
datasetPath = 'dataset/firstorder/kernel5/dataset.csv'

# %%
# Parameters
datasetPath = "dataset/glrlm/kernel5/1.dataset.csv"

# %%
# train/validation/test = 70/10/20
dataset = pd.read_csv(datasetPath)

train_data, temp_data = train_test_split(dataset, test_size=0.3, random_state=42)
validation_data, test_data = train_test_split(temp_data, test_size=2/3, random_state=42)

# %%
from sklearn.utils.class_weight import compute_class_weight

# tinh class weight tren tap train
classes = np.array([0, 1])
weights = compute_class_weight(class_weight="balanced", classes=classes, y=train_data["label"])
class_weight = {0: weights[0], 1: weights[1]}

# gan sample_weight cho tung dong
train_data["sample_weight"] = train_data["label"].map(class_weight)
validation_data["sample_weight"] = validation_data["label"].map(class_weight)
test_data["sample_weight"] = test_data["label"].map(class_weight)

# Convert the dataset into a TensorFlow dataset.
train_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    train_data, label="label", weight="sample_weight"
)         
val_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    validation_data, label="label", weight="sample_weight"
)
test_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    test_data, label="label", weight="sample_weight"
)
# Out:
# 2026-08-15 05:18:24.359308: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:984] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2026-08-15 05:18:24.360667: W tensorflow/core/common_runtime/gpu/gpu_device.cc:2251] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...

# %%
import keras

# %%
# %%time

# Train a Random Forest model.
model = tfdf.keras.RandomForestModel()

# Add evaluation metrics
model.compile(
    metrics=["accuracy"]
)
model.fit(x=train_ds)

# # Train a Gradient Boosted Trees model.
# model = tfdf.keras.GradientBoostedTreesModel(num_trees=1500)
# model.fit(train_ds)
# Out:
# Use /tmp/tmpjsh7q6jy as temporary training directory
# Reading training dataset...
# Training dataset read in 0:00:02.618496. Found 849 examples.
# Training model...
# Model trained in 0:00:00.048935
# Compiling model...
# [INFO 26-08-15 05:18:27.1964 UTC kernel.cc:1233] Loading model from path /tmp/tmpjsh7q6jy/model/ with prefix 5703e0ac2d2a47ed
# [INFO 26-08-15 05:18:27.2022 UTC decision_forest.cc:734] Model loaded with 300 root(s), 4446 node(s), and 16 input feature(s).
# [INFO 26-08-15 05:18:27.2022 UTC abstract_model.cc:1362] Engine "RandomForestOptPred" built
# [INFO 26-08-15 05:18:27.2022 UTC kernel.cc:1061] Use fast generic engine
# Model compiled.
# CPU times: user 5.46 s, sys: 131 ms, total: 5.59 s
# Wall time: 5.84 s

# %%
# Evaluate the model
evaluate = model.evaluate(val_ds, return_dict=True)
print()

for name, value in evaluate.items():
    print(f"{name}: {value:.4f}")
# Out:
# WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 1/1 [==============================] - ETA: 0s - loss: 0.0000e+00 - accuracy: 0.9752
# 1/1 [==============================] - 3s 3s/step - loss: 0.0000e+00 - accuracy: 0.9752
# loss: 0.0000
# accuracy: 0.9752

# %%
# Model Summary
model.summary()
# Out:
# Model: "random_forest_model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
# =================================================================
# Total params: 1 (1.00 Byte)
# Trainable params: 0 (0.00 Byte)
# Non-trainable params: 1 (1.00 Byte)
# _________________________________________________________________
# Type: "RANDOM_FOREST"
# Task: CLASSIFICATION
# Label: "__LABEL"
#
# Input Features (16):
# 	GrayLevelNonUniformity
# 	GrayLevelNonUniformityNormalized
# 	GrayLevelVariance
# 	HighGrayLevelRunEmphasis
# 	LongRunEmphasis
# 	LongRunHighGrayLevelEmphasis
# 	LongRunLowGrayLevelEmphasis
# 	LowGrayLevelRunEmphasis
# 	RunEntropy
# 	RunLengthNonUniformity
# 	RunLengthNonUniformityNormalized
# 	RunPercentage
# 	RunVariance
# 	ShortRunEmphasis
# 	ShortRunHighGrayLevelEmphasis
# 	ShortRunLowGrayLevelEmphasis
#
# Trained with weights
#
# Variable Importance: INV_MEAN_MIN_DEPTH:
#     1.    "ShortRunHighGrayLevelEmphasis"  0.338466 ################
#     2.         "HighGrayLevelRunEmphasis"  0.310680 ###########
#     3.     "LongRunHighGrayLevelEmphasis"  0.295286 #########
#     4.      "LongRunLowGrayLevelEmphasis"  0.271549 ######
#     5.          "LowGrayLevelRunEmphasis"  0.265257 #####
#     6.     "ShortRunLowGrayLevelEmphasis"  0.262635 ####
#     7.                       "RunEntropy"  0.247843 ##
#     8. "GrayLevelNonUniformityNormalized"  0.247508 ##
#     9.                "GrayLevelVariance"  0.246831 ##
#    10.           "GrayLevelNonUniformity"  0.242124 #
#    11.                      "RunVariance"  0.232620
#    12.                  "LongRunEmphasis"  0.230873
#    13.           "RunLengthNonUniformity"  0.230624
#    14.                 "ShortRunEmphasis"  0.230299
#    15.                    "RunPercentage"  0.230282
#    16. "RunLengthNonUniformityNormalized"  0.229640
#
# Variable Importance: NUM_AS_ROOT:
#     1.    "ShortRunHighGrayLevelEmphasis" 83.000000 ################
#     2.         "HighGrayLevelRunEmphasis" 68.000000 #############
#     3.     "LongRunHighGrayLevelEmphasis" 61.000000 ###########
#     4.      "LongRunLowGrayLevelEmphasis" 26.000000 ####
#     5.          "LowGrayLevelRunEmphasis" 23.000000 ####
#     6.     "ShortRunLowGrayLevelEmphasis" 19.000000 ###
#     7. "GrayLevelNonUniformityNormalized"  8.000000 #
#     8.           "GrayLevelNonUniformity"  6.000000
#     9.                       "RunEntropy"  3.000000
#    10.                "GrayLevelVariance"  2.000000
#    11.                  "LongRunEmphasis"  1.000000
#
# Variable Importance: NUM_NODES:
#     1.    "ShortRunHighGrayLevelEmphasis" 279.000000 ################
#     2.         "HighGrayLevelRunEmphasis" 220.000000 ############
#     3.      "LongRunLowGrayLevelEmphasis" 198.000000 ##########
#     4.     "LongRunHighGrayLevelEmphasis" 197.000000 ##########
#     5.                       "RunEntropy" 172.000000 ########
#     6.          "LowGrayLevelRunEmphasis" 166.000000 ########
#     7.     "ShortRunLowGrayLevelEmphasis" 165.000000 ########
#     8.                "GrayLevelVariance" 163.000000 ########
#     9.           "GrayLevelNonUniformity" 134.000000 ######
#    10. "GrayLevelNonUniformityNormalized" 134.000000 ######
#    11.                      "RunVariance" 48.000000
#    12.           "RunLengthNonUniformity" 47.000000
#    13. "RunLengthNonUniformityNormalized" 38.000000
#    14.                    "RunPercentage" 38.000000
#    15.                  "LongRunEmphasis" 37.000000
#    16.                 "ShortRunEmphasis" 37.000000
#
# Variable Importance: SUM_SCORE:
#     1.    "ShortRunHighGrayLevelEmphasis" 48526.618815 ################
#     2.         "HighGrayLevelRunEmphasis" 37326.603882 ############
#     3.     "LongRunHighGrayLevelEmphasis" 32075.982130 ##########
#     4.      "LongRunLowGrayLevelEmphasis" 12093.252833 ###
#     5.          "LowGrayLevelRunEmphasis" 11393.354479 ###
#     6.     "ShortRunLowGrayLevelEmphasis" 9896.797936 ###
#     7. "GrayLevelNonUniformityNormalized" 4773.365093 #
#     8.                       "RunEntropy" 4470.128198 #
#     9.           "GrayLevelNonUniformity" 4459.648011 #
#    10.                "GrayLevelVariance" 2850.974533
#    11.                      "RunVariance" 807.845755
#    12. "RunLengthNonUniformityNormalized" 666.006561
#    13.                  "LongRunEmphasis" 591.714967
#    14.           "RunLengthNonUniformity" 513.526238
#    15.                 "ShortRunEmphasis" 461.473024
#    16.                    "RunPercentage" 302.241263
#
#
#
# Winner takes all: true
# Out-of-bag evaluation: accuracy:0.954184 logloss:0.115441
# Number of trees: 300
# Total number of nodes: 4446
#
# Number of nodes by tree:
# Count: 300 Average: 14.82 StdDev: 3.1719
# Min: 5 Max: 23 Ignored: 0
# ----------------------------------------------
# [  5,  6)  1   0.33%   0.33%
# [  6,  7)  0   0.00%   0.33%
# [  7,  8)  4   1.33%   1.67%
# [  8,  9)  0   0.00%   1.67%
# [  9, 10) 13   4.33%   6.00% ##
# [ 10, 11)  0   0.00%   6.00%
# [ 11, 12) 33  11.00%  17.00% ####
# [ 12, 13)  0   0.00%  17.00%
# [ 13, 14) 66  22.00%  39.00% ########
# [ 14, 15)  0   0.00%  39.00%
# [ 15, 16) 82  27.33%  66.33% ##########
# [ 16, 17)  0   0.00%  66.33%
# [ 17, 18) 60  20.00%  86.33% #######
# [ 18, 19)  0   0.00%  86.33%
# [ 19, 20) 25   8.33%  94.67% ###
# [ 20, 21)  0   0.00%  94.67%
# [ 21, 22)  9   3.00%  97.67% #
# [ 22, 23)  0   0.00%  97.67%
# [ 23, 23]  7   2.33% 100.00% #
#
# Depth by leafs:
# Count: 2373 Average: 3.49305 StdDev: 1.26995
# Min: 1 Max: 8 Ignored: 0
# ----------------------------------------------
# [ 1, 2)  95   4.00%   4.00% #
# [ 2, 3) 460  19.38%  23.39% #######
# [ 3, 4) 675  28.45%  51.83% ##########
# [ 4, 5) 636  26.80%  78.63% #########
# [ 5, 6) 360  15.17%  93.81% #####
# [ 6, 7) 126   5.31%  99.12% ##
# [ 7, 8)  19   0.80%  99.92%
# [ 8, 8]   2   0.08% 100.00%
#
# Number of training obs by leaf:
# Count: 2373 Average: 107.332 StdDev: 240.352
# Min: 5 Max: 804 Ignored: 0
# ----------------------------------------------
# [   5,  45) 1971  83.06%  83.06% ##########
# [  45,  85)   83   3.50%  86.56%
# [  85, 125)    2   0.08%  86.64%
# [ 125, 165)    4   0.17%  86.81%
# [ 165, 205)    5   0.21%  87.02%
# [ 205, 245)    3   0.13%  87.15%
# [ 245, 285)    2   0.08%  87.23%
# [ 285, 325)    1   0.04%  87.27%
# [ 325, 365)    2   0.08%  87.36%
# [ 365, 405)    3   0.13%  87.48%
# [ 405, 445)    1   0.04%  87.53%
# [ 445, 485)    1   0.04%  87.57%
# [ 485, 525)    1   0.04%  87.61%
# [ 525, 565)    2   0.08%  87.69%
# [ 565, 605)    4   0.17%  87.86%
# [ 605, 645)    4   0.17%  88.03%
# [ 645, 685)   11   0.46%  88.50%
# [ 685, 725)   54   2.28%  90.77%
# [ 725, 765)  118   4.97%  95.74% #
# [ 765, 804]  101   4.26% 100.00% #
#
# Attribute in nodes:
# 	279 : ShortRunHighGrayLevelEmphasis [NUMERICAL]
# 	220 : HighGrayLevelRunEmphasis [NUMERICAL]
# 	198 : LongRunLowGrayLevelEmphasis [NUMERICAL]
# 	197 : LongRunHighGrayLevelEmphasis [NUMERICAL]
# 	172 : RunEntropy [NUMERICAL]
# 	166 : LowGrayLevelRunEmphasis [NUMERICAL]
# 	165 : ShortRunLowGrayLevelEmphasis [NUMERICAL]
# 	163 : GrayLevelVariance [NUMERICAL]
# 	134 : GrayLevelNonUniformityNormalized [NUMERICAL]
# 	134 : GrayLevelNonUniformity [NUMERICAL]
# 	48 : RunVariance [NUMERICAL]
# 	47 : RunLengthNonUniformity [NUMERICAL]
# 	38 : RunPercentage [NUMERICAL]
# 	38 : RunLengthNonUniformityNormalized [NUMERICAL]
# 	37 : ShortRunEmphasis [NUMERICAL]
# 	37 : LongRunEmphasis [NUMERICAL]
#
# Attribute in nodes with depth <= 0:
# 	83 : ShortRunHighGrayLevelEmphasis [NUMERICAL]
# 	68 : HighGrayLevelRunEmphasis [NUMERICAL]
# 	61 : LongRunHighGrayLevelEmphasis [NUMERICAL]
# 	26 : LongRunLowGrayLevelEmphasis [NUMERICAL]
# 	23 : LowGrayLevelRunEmphasis [NUMERICAL]
# 	19 : ShortRunLowGrayLevelEmphasis [NUMERICAL]
# 	8 : GrayLevelNonUniformityNormalized [NUMERICAL]
# 	6 : GrayLevelNonUniformity [NUMERICAL]
# 	3 : RunEntropy [NUMERICAL]
# 	2 : GrayLevelVariance [NUMERICAL]
# 	1 : LongRunEmphasis [NUMERICAL]
#
# Attribute in nodes with depth <= 1:
# 	186 : ShortRunHighGrayLevelEmphasis [NUMERICAL]
# 	144 : HighGrayLevelRunEmphasis [NUMERICAL]
# 	111 : LongRunHighGrayLevelEmphasis [NUMERICAL]
# 	65 : LongRunLowGrayLevelEmphasis [NUMERICAL]
# 	54 : LowGrayLevelRunEmphasis [NUMERICAL]
# 	50 : ShortRunLowGrayLevelEmphasis [NUMERICAL]
# 	45 : GrayLevelNonUniformityNormalized [NUMERICAL]
# 	45 : GrayLevelNonUniformity [NUMERICAL]
# 	38 : RunEntropy [NUMERICAL]
# 	22 : GrayLevelVariance [NUMERICAL]
# 	11 : RunVariance [NUMERICAL]
# 	9 : LongRunEmphasis [NUMERICAL]
# 	8 : RunLengthNonUniformityNormalized [NUMERICAL]
# 	8 : RunLengthNonUniformity [NUMERICAL]
# 	6 : RunPercentage [NUMERICAL]
# 	3 : ShortRunEmphasis [NUMERICAL]
#
# Attribute in nodes with depth <= 2:
# 	238 : ShortRunHighGrayLevelEmphasis [NUMERICAL]
# 	180 : HighGrayLevelRunEmphasis [NUMERICAL]
# 	158 : LongRunHighGrayLevelEmphasis [NUMERICAL]
# 	123 : LongRunLowGrayLevelEmphasis [NUMERICAL]
# 	109 : LowGrayLevelRunEmphasis [NUMERICAL]
# 	98 : RunEntropy [NUMERICAL]
# 	95 : ShortRunLowGrayLevelEmphasis [NUMERICAL]
# 	92 : GrayLevelNonUniformityNormalized [NUMERICAL]
# 	82 : GrayLevelNonUniformity [NUMERICAL]
# 	76 : GrayLevelVariance [NUMERICAL]
# 	25 : RunVariance [NUMERICAL]
# 	19 : LongRunEmphasis [NUMERICAL]
# 	17 : RunLengthNonUniformityNormalized [NUMERICAL]
# 	16 : RunLengthNonUniformity [NUMERICAL]
# 	15 : ShortRunEmphasis [NUMERICAL]
# 	12 : RunPercentage [NUMERICAL]
#
# Attribute in nodes with depth <= 3:
# 	262 : ShortRunHighGrayLevelEmphasis [NUMERICAL]
# 	198 : HighGrayLevelRunEmphasis [NUMERICAL]
# 	179 : LongRunHighGrayLevelEmphasis [NUMERICAL]
# 	176 : LongRunLowGrayLevelEmphasis [NUMERICAL]
# 	145 : RunEntropy [NUMERICAL]
# 	145 : LowGrayLevelRunEmphasis [NUMERICAL]
# 	137 : GrayLevelVariance [NUMERICAL]
# 	136 : ShortRunLowGrayLevelEmphasis [NUMERICAL]
# 	115 : GrayLevelNonUniformityNormalized [NUMERICAL]
# 	109 : GrayLevelNonUniformity [NUMERICAL]
# 	39 : RunVariance [NUMERICAL]
# 	31 : RunLengthNonUniformity [NUMERICAL]
# 	29 : LongRunEmphasis [NUMERICAL]
# 	27 : ShortRunEmphasis [NUMERICAL]
# 	26 : RunPercentage [NUMERICAL]
# 	26 : RunLengthNonUniformityNormalized [NUMERICAL]
#
# Attribute in nodes with depth <= 5:
# 	278 : ShortRunHighGrayLevelEmphasis [NUMERICAL]
# 	218 : HighGrayLevelRunEmphasis [NUMERICAL]
# 	198 : LongRunLowGrayLevelEmphasis [NUMERICAL]
# 	197 : LongRunHighGrayLevelEmphasis [NUMERICAL]
# 	171 : RunEntropy [NUMERICAL]
# 	165 : ShortRunLowGrayLevelEmphasis [NUMERICAL]
# 	165 : LowGrayLevelRunEmphasis [NUMERICAL]
# 	161 : GrayLevelVariance [NUMERICAL]
# 	134 : GrayLevelNonUniformityNormalized [NUMERICAL]
# 	133 : GrayLevelNonUniformity [NUMERICAL]
# 	48 : RunVariance [NUMERICAL]
# 	47 : RunLengthNonUniformity [NUMERICAL]
# 	37 : ShortRunEmphasis [NUMERICAL]
# 	37 : RunLengthNonUniformityNormalized [NUMERICAL]
# 	37 : LongRunEmphasis [NUMERICAL]
# 	36 : RunPercentage [NUMERICAL]
#
# Condition type in nodes:
# 	2073 : HigherCondition
# Condition type in nodes with depth <= 0:
# 	300 : HigherCondition
# Condition type in nodes with depth <= 1:
# 	805 : HigherCondition
# Condition type in nodes with depth <= 2:
# 	1355 : HigherCondition
# Condition type in nodes with depth <= 3:
# 	1780 : HigherCondition
# Condition type in nodes with depth <= 5:
# 	2062 : HigherCondition
# Node format: NOT_SET
#
# Training OOB:
# 	trees: 1, Out-of-bag evaluation: accuracy:0.858777 logloss:5.09018
# 	trees: 13, Out-of-bag evaluation: accuracy:0.933821 logloss:1.27962
# 	trees: 25, Out-of-bag evaluation: accuracy:0.943355 logloss:0.488529
# 	trees: 35, Out-of-bag evaluation: accuracy:0.953559 logloss:0.145068
# 	trees: 45, Out-of-bag evaluation: accuracy:0.943355 logloss:0.148705
# 	trees: 55, Out-of-bag evaluation: accuracy:0.94398 logloss:0.133109
# 	trees: 65, Out-of-bag evaluation: accuracy:0.954184 logloss:0.132364
# 	trees: 75, Out-of-bag evaluation: accuracy:0.954184 logloss:0.135137
# 	trees: 85, Out-of-bag evaluation: accuracy:0.954184 logloss:0.134792
# 	trees: 95, Out-of-bag evaluation: accuracy:0.954809 logloss:0.1274
# 	trees: 106, Out-of-bag evaluation: accuracy:0.954184 logloss:0.128732
# 	trees: 117, Out-of-bag evaluation: accuracy:0.954809 logloss:0.133178
# 	trees: 128, Out-of-bag evaluation: accuracy:0.954809 logloss:0.135068
# 	trees: 138, Out-of-bag evaluation: accuracy:0.954809 logloss:0.136586
# 	trees: 150, Out-of-bag evaluation: accuracy:0.954809 logloss:0.139848
# 	trees: 160, Out-of-bag evaluation: accuracy:0.944605 logloss:0.142124
# 	trees: 170, Out-of-bag evaluation: accuracy:0.954809 logloss:0.122675
# 	trees: 180, Out-of-bag evaluation: accuracy:0.954809 logloss:0.12341
# 	trees: 193, Out-of-bag evaluation: accuracy:0.944605 logloss:0.119302
# 	trees: 203, Out-of-bag evaluation: accuracy:0.94398 logloss:0.117877
# 	trees: 213, Out-of-bag evaluation: accuracy:0.94398 logloss:0.119225
# 	trees: 223, Out-of-bag evaluation: accuracy:0.954184 logloss:0.119458
# 	trees: 233, Out-of-bag evaluation: accuracy:0.954184 logloss:0.119347
# 	trees: 244, Out-of-bag evaluation: accuracy:0.954184 logloss:0.119753
# 	trees: 254, Out-of-bag evaluation: accuracy:0.953559 logloss:0.117532
# 	trees: 264, Out-of-bag evaluation: accuracy:0.953559 logloss:0.117492
# 	trees: 274, Out-of-bag evaluation: accuracy:0.954184 logloss:0.119283
# 	trees: 284, Out-of-bag evaluation: accuracy:0.954184 logloss:0.117154
# 	trees: 297, Out-of-bag evaluation: accuracy:0.954184 logloss:0.11525
# 	trees: 300, Out-of-bag evaluation: accuracy:0.954184 logloss:0.115441

# %%
# Model features
model.make_inspector().features()
# Out:
# ["GrayLevelNonUniformity" (1; #0),
#  "GrayLevelNonUniformityNormalized" (1; #1),
#  "GrayLevelVariance" (1; #2),
#  "HighGrayLevelRunEmphasis" (1; #3),
#  "LongRunEmphasis" (1; #4),
#  "LongRunHighGrayLevelEmphasis" (1; #5),
#  "LongRunLowGrayLevelEmphasis" (1; #6),
#  "LowGrayLevelRunEmphasis" (1; #7),
#  "RunEntropy" (1; #8),
#  "RunLengthNonUniformity" (1; #9),
#  "RunLengthNonUniformityNormalized" (1; #10),
#  "RunPercentage" (1; #11),
#  "RunVariance" (1; #12),
#  "ShortRunEmphasis" (1; #13),
#  "ShortRunHighGrayLevelEmphasis" (1; #14),
#  "ShortRunLowGrayLevelEmphasis" (1; #15)]

# %%
# Feature importance
model.make_inspector().variable_importances()
# Out:
# {'INV_MEAN_MIN_DEPTH': [("ShortRunHighGrayLevelEmphasis" (1; #14),
#    0.33846620838602537),
#   ("HighGrayLevelRunEmphasis" (1; #3), 0.3106798437858707),
#   ("LongRunHighGrayLevelEmphasis" (1; #5), 0.29528626398322144),
#   ("LongRunLowGrayLevelEmphasis" (1; #6), 0.27154872702880967),
#   ("LowGrayLevelRunEmphasis" (1; #7), 0.26525731123438406),
#   ("ShortRunLowGrayLevelEmphasis" (1; #15), 0.26263514766973844),
#   ("RunEntropy" (1; #8), 0.2478431521214238),
#   ("GrayLevelNonUniformityNormalized" (1; #1), 0.247507999812137),
#   ("GrayLevelVariance" (1; #2), 0.24683088994200647),
#   ("GrayLevelNonUniformity" (1; #0), 0.24212422958652705),
#   ("RunVariance" (1; #12), 0.23262020619784055),
#   ("LongRunEmphasis" (1; #4), 0.2308729236949165),
#   ("RunLengthNonUniformity" (1; #9), 0.23062387807972756),
#   ("ShortRunEmphasis" (1; #13), 0.23029928244714334),
#   ("RunPercentage" (1; #11), 0.23028177034843098),
#   ("RunLengthNonUniformityNormalized" (1; #10), 0.22964013490998972)],
#  'NUM_AS_ROOT': [("ShortRunHighGrayLevelEmphasis" (1; #14), 83.0),
#   ("HighGrayLevelRunEmphasis" (1; #3), 68.0),
#   ("LongRunHighGrayLevelEmphasis" (1; #5), 61.0),
#   ("LongRunLowGrayLevelEmphasis" (1; #6), 26.0),
#   ("LowGrayLevelRunEmphasis" (1; #7), 23.0),
#   ("ShortRunLowGrayLevelEmphasis" (1; #15), 19.0),
#   ("GrayLevelNonUniformityNormalized" (1; #1), 8.0),
#   ("GrayLevelNonUniformity" (1; #0), 6.0),
#   ("RunEntropy" (1; #8), 3.0),
#   ("GrayLevelVariance" (1; #2), 2.0),
#   ("LongRunEmphasis" (1; #4), 1.0)],
#  'SUM_SCORE': [("ShortRunHighGrayLevelEmphasis" (1; #14), 48526.61881504404),
#   ("HighGrayLevelRunEmphasis" (1; #3), 37326.60388215051),
#   ("LongRunHighGrayLevelEmphasis" (1; #5), 32075.98212979038),
#   ("LongRunLowGrayLevelEmphasis" (1; #6), 12093.25283267714),
#   ("LowGrayLevelRunEmphasis" (1; #7), 11393.354479084455),
#   ("ShortRunLowGrayLevelEmphasis" (1; #15), 9896.797936060171),
#   ("GrayLevelNonUniformityNormalized" (1; #1), 4773.365092537454),
#   ("RunEntropy" (1; #8), 4470.128197893475),
#   ("GrayLevelNonUniformity" (1; #0), 4459.648011424954),
#   ("GrayLevelVariance" (1; #2), 2850.9745325423296),
#   ("RunVariance" (1; #12), 807.8457547178517),
#   ("RunLengthNonUniformityNormalized" (1; #10), 666.0065612218208),
#   ("LongRunEmphasis" (1; #4), 591.7149667428913),
#   ("RunLengthNonUniformity" (1; #9), 513.5262379312293),
#   ("ShortRunEmphasis" (1; #13), 461.47302439322584),
#   ("RunPercentage" (1; #11), 302.2412626582938)],
#  'NUM_NODES': [("ShortRunHighGrayLevelEmphasis" (1; #14), 279.0),
#   ("HighGrayLevelRunEmphasis" (1; #3), 220.0),
#   ("LongRunLowGrayLevelEmphasis" (1; #6), 198.0),
#   ("LongRunHighGrayLevelEmphasis" (1; #5), 197.0),
#   ("RunEntropy" (1; #8), 172.0),
#   ("LowGrayLevelRunEmphasis" (1; #7), 166.0),
#   ("ShortRunLowGrayLevelEmphasis" (1; #15), 165.0),
#   ("GrayLevelVariance" (1; #2), 163.0),
#   ("GrayLevelNonUniformity" (1; #0), 134.0),
#   ("GrayLevelNonUniformityNormalized" (1; #1), 134.0),
#   ("RunVariance" (1; #12), 48.0),
#   ("RunLengthNonUniformity" (1; #9), 47.0),
#   ("RunLengthNonUniformityNormalized" (1; #10), 38.0),
#   ("RunPercentage" (1; #11), 38.0),
#   ("LongRunEmphasis" (1; #4), 37.0),
#   ("ShortRunEmphasis" (1; #13), 37.0)]}

# %%
# Model self evaluation
model.make_inspector().evaluation()
# Out:
# Evaluation(num_examples=849, accuracy=0.9541836731475304, loss=0.11544105006731457, rmse=None, ndcg=None, aucs=None, auuc=None, qini=None)

# %%
logs = model.make_inspector().training_logs()

plt.figure(figsize=(12, 4))
plt.subplot(1, 2, 1)
plt.plot([log.num_trees for log in logs], [log.evaluation.accuracy for log in logs])
plt.xlabel("Number of trees")
plt.ylabel("Accuracy (out-of-bag)")
plt.subplot(1, 2, 2)
plt.plot([log.num_trees for log in logs], [log.evaluation.loss for log in logs])
plt.xlabel("Number of trees")
plt.ylabel("Logloss (out-of-bag)")
plt.show()

# %% [markdown]
# Calculate the score of our hold-out validation dataset

# %%
predictions = model.predict(val_ds)
y_true      = validation_data["label"]

from sklearn.metrics import roc_auc_score
ROC_AUC = roc_auc_score(y_true, predictions)
print("The ROC AUC score is %.5f" % ROC_AUC )
# Out:
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 63ms/step
# The ROC AUC score is 0.99145

# %%
# Compute binary classification metrics with sklearn
import numpy as np
from sklearn.metrics import (
    accuracy_score,
    precision_score,
    recall_score,
    f1_score,
    roc_auc_score,
    average_precision_score,
    confusion_matrix,
    classification_report,
    matthews_corrcoef,
    log_loss,
    brier_score_loss,
)

# Get predictions (probabilities or class labels)
preds = model.predict(test_ds)
# If model outputs probabilities, convert to labels by threshold 0.5
if preds.ndim == 2:
    # For TFDF classification, preds may be class probabilities with shape (N, 2)
    if preds.shape[1] == 2:
        pos_probs = preds[:, 1]
    else:
        # If single-probability column (positive class)
        pos_probs = preds[:, -1]
    y_pred = (pos_probs >= 0.5).astype(int)
else:
    # Already class labels
    y_pred = preds.astype(int)
    pos_probs = None

# Ground truth labels (must be 0/1 integers)
y_true = test_data["label"].astype(int).to_numpy()

# Core metrics
metrics = {}
metrics["accuracy"] = accuracy_score(y_true, y_pred)
metrics["precision"] = precision_score(y_true, y_pred, zero_division=0)
metrics["recall"] = recall_score(y_true, y_pred, zero_division=0)
metrics["f1"] = f1_score(y_true, y_pred, zero_division=0)
metrics["mcc"] = matthews_corrcoef(y_true, y_pred)

# Probabilistic metrics (only if we have probabilities)
if pos_probs is not None:
    metrics["roc_auc"] = roc_auc_score(y_true, pos_probs)
    metrics["pr_auc"] = average_precision_score(y_true, pos_probs)
    metrics["log_loss"] = log_loss(y_true, pos_probs, labels=[0,1])
    metrics["brier_score"] = brier_score_loss(y_true, pos_probs)

# Confusion matrix and detailed report
cm = confusion_matrix(y_true, y_pred, labels=[0,1])
report = classification_report(y_true, y_pred, digits=4)

print("Sklearn binary metrics:")
for k, v in metrics.items():
    print(f"{k}: {v:.4f}")
print("\nConfusion matrix:\n", cm)
print("\nClassification report:\n", report)
# Out:
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 63ms/step
# Sklearn binary metrics:
# accuracy: 0.9836
# precision: 0.8571
# recall: 0.9474
# f1: 0.9000
# mcc: 0.8924
# roc_auc: 0.9954
# pr_auc: 0.9730
# log_loss: 0.0448
# brier_score: 0.0122
#
# Confusion matrix:
#  [[222   3]
#  [  1  18]]
#
# Classification report:
#                precision    recall  f1-score   support
#
#            0     0.9955    0.9867    0.9911       225
#            1     0.8571    0.9474    0.9000        19
#
#     accuracy                         0.9836       244
#    macro avg     0.9263    0.9670    0.9455       244
# weighted avg     0.9847    0.9836    0.9840       244
