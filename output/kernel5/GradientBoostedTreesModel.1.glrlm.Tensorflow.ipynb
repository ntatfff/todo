# %%
# Import packages and modules
import numpy  as np
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow_decision_forests as tfdf

from sklearn.model_selection import train_test_split
# Out:
# 2026-08-15 05:03:33.171704: I tensorflow/core/util/port.cc:113] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2026-08-15 05:03:33.546529: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2026-08-15 05:03:38.355733: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
# Check the version of TensorFlow Decision Forests
print("Found TensorFlow Decision Forests v" + tfdf.__version__)
# Out:
# Found TensorFlow Decision Forests v1.9.1

# %%
datasetPath = 'dataset/firstorder/kernel5/dataset.csv'

# %%
# Parameters
datasetPath = "dataset/glrlm/kernel5/1.dataset.csv"

# %%
# train/validation/test = 70/10/20
dataset = pd.read_csv(datasetPath)

train_data, temp_data = train_test_split(dataset, test_size=0.3, random_state=42)
validation_data, test_data = train_test_split(temp_data, test_size=2/3, random_state=42)

# %%
from sklearn.utils.class_weight import compute_class_weight

# tinh class weight tren tap train
classes = np.array([0, 1])
weights = compute_class_weight(class_weight="balanced", classes=classes, y=train_data["label"])
class_weight = {0: weights[0], 1: weights[1]}

# gan sample_weight cho tung dong
train_data["sample_weight"] = train_data["label"].map(class_weight)
validation_data["sample_weight"] = validation_data["label"].map(class_weight)
test_data["sample_weight"] = test_data["label"].map(class_weight)

# Convert the dataset into a TensorFlow dataset.
train_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    train_data, label="label", weight="sample_weight"
)         
val_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    validation_data, label="label", weight="sample_weight"
)
test_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    test_data, label="label", weight="sample_weight"
)
# Out:
# 2026-08-15 05:03:51.983323: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:984] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2026-08-15 05:03:51.984746: W tensorflow/core/common_runtime/gpu/gpu_device.cc:2251] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...

# %%
import keras

# %%
# %%time

# Train a Gradient Boosted Trees model.
model = tfdf.keras.GradientBoostedTreesModel()

# Add evaluation metrics
model.compile(
    metrics=["accuracy"]
)
model.fit(x=train_ds)

# # Train a Gradient Boosted Trees model.
# model = tfdf.keras.GradientBoostedTreesModel(num_trees=1500)
# model.fit(train_ds)
# Out:
# Use /tmp/tmpf0w04zak as temporary training directory
# Reading training dataset...
# [WARNING 26-08-15 05:03:52.1366 UTC gradient_boosted_trees.cc:1840] "goss_alpha" set but "sampling_method" not equal to "GOSS".
# [WARNING 26-08-15 05:03:52.1370 UTC gradient_boosted_trees.cc:1851] "goss_beta" set but "sampling_method" not equal to "GOSS".
# [WARNING 26-08-15 05:03:52.1370 UTC gradient_boosted_trees.cc:1865] "selective_gradient_boosting_ratio" set but "sampling_method" not equal to "SELGB".
# Training dataset read in 0:00:02.688782. Found 849 examples.
# Training model...
# Model trained in 0:00:00.228000
# Compiling model...
# [INFO 26-08-15 05:03:55.0822 UTC kernel.cc:1233] Loading model from path /tmp/tmpf0w04zak/model/ with prefix 312fba5000654bb4
# [INFO 26-08-15 05:03:55.0842 UTC quick_scorer_extended.cc:911] The binary was compiled without AVX2 support, but your CPU supports it. Enable it for faster model inference.
# [INFO 26-08-15 05:03:55.0843 UTC abstract_model.cc:1362] Engine "GradientBoostedTreesQuickScorerExtended" built
# [INFO 26-08-15 05:03:55.0843 UTC kernel.cc:1061] Use fast generic engine
# Model compiled.
# CPU times: user 5.76 s, sys: 343 ms, total: 6.1 s
# Wall time: 6.16 s

# %%
# Evaluate the model
evaluate = model.evaluate(val_ds, return_dict=True)
print()

for name, value in evaluate.items():
    print(f"{name}: {value:.4f}")
# Out:
# WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 1/1 [==============================] - ETA: 0s - loss: 0.0000e+00 - accuracy: 0.9752
# 1/1 [==============================] - 3s 3s/step - loss: 0.0000e+00 - accuracy: 0.9752
# loss: 0.0000
# accuracy: 0.9752

# %%
# Model Summary
model.summary()
# Out:
# Model: "gradient_boosted_trees_model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
# =================================================================
# Total params: 1 (1.00 Byte)
# Trainable params: 0 (0.00 Byte)
# Non-trainable params: 1 (1.00 Byte)
# _________________________________________________________________
# Type: "GRADIENT_BOOSTED_TREES"
# Task: CLASSIFICATION
# Label: "__LABEL"
#
# Input Features (16):
# 	GrayLevelNonUniformity
# 	GrayLevelNonUniformityNormalized
# 	GrayLevelVariance
# 	HighGrayLevelRunEmphasis
# 	LongRunEmphasis
# 	LongRunHighGrayLevelEmphasis
# 	LongRunLowGrayLevelEmphasis
# 	LowGrayLevelRunEmphasis
# 	RunEntropy
# 	RunLengthNonUniformity
# 	RunLengthNonUniformityNormalized
# 	RunPercentage
# 	RunVariance
# 	ShortRunEmphasis
# 	ShortRunHighGrayLevelEmphasis
# 	ShortRunLowGrayLevelEmphasis
#
# Trained with weights
#
# Variable Importance: INV_MEAN_MIN_DEPTH:
#     1.    "ShortRunHighGrayLevelEmphasis"  0.449292 ################
#     2.     "LongRunHighGrayLevelEmphasis"  0.341410 #########
#     3.                       "RunEntropy"  0.242694 ##
#     4.      "LongRunLowGrayLevelEmphasis"  0.233790 ##
#     5.     "ShortRunLowGrayLevelEmphasis"  0.223431 #
#     6.                "GrayLevelVariance"  0.220196 #
#     7.          "LowGrayLevelRunEmphasis"  0.218884 #
#     8.           "GrayLevelNonUniformity"  0.217076 #
#     9. "GrayLevelNonUniformityNormalized"  0.207123
#    10.         "HighGrayLevelRunEmphasis"  0.206427
#    11.                      "RunVariance"  0.199826
#    12. "RunLengthNonUniformityNormalized"  0.197899
#    13.           "RunLengthNonUniformity"  0.197524
#    14.                 "ShortRunEmphasis"  0.196164
#    15.                    "RunPercentage"  0.196023
#    16.                  "LongRunEmphasis"  0.195428
#
# Variable Importance: NUM_AS_ROOT:
#     1.  "LongRunHighGrayLevelEmphasis" 15.000000
#     2. "ShortRunHighGrayLevelEmphasis" 15.000000
#
# Variable Importance: NUM_NODES:
#     1.                       "RunEntropy" 60.000000 ################
#     2.     "LongRunHighGrayLevelEmphasis" 48.000000 ############
#     3.    "ShortRunHighGrayLevelEmphasis" 42.000000 ##########
#     4.                "GrayLevelVariance" 40.000000 ##########
#     5.      "LongRunLowGrayLevelEmphasis" 39.000000 ##########
#     6.           "GrayLevelNonUniformity" 35.000000 ########
#     7.     "ShortRunLowGrayLevelEmphasis" 28.000000 ######
#     8. "GrayLevelNonUniformityNormalized" 23.000000 #####
#     9.          "LowGrayLevelRunEmphasis" 20.000000 ####
#    10.         "HighGrayLevelRunEmphasis" 19.000000 ####
#    11.                      "RunVariance"  9.000000 #
#    12. "RunLengthNonUniformityNormalized"  8.000000 #
#    13.           "RunLengthNonUniformity"  7.000000
#    14.                 "ShortRunEmphasis"  5.000000
#    15.                  "LongRunEmphasis"  4.000000
#    16.                    "RunPercentage"  4.000000
#
# Variable Importance: SUM_SCORE:
#     1.     "LongRunHighGrayLevelEmphasis" 846.817932 ################
#     2.    "ShortRunHighGrayLevelEmphasis" 56.791389 #
#     3.                       "RunEntropy" 45.163170
#     4.           "GrayLevelNonUniformity" 33.899987
#     5.     "ShortRunLowGrayLevelEmphasis" 18.503050
#     6.      "LongRunLowGrayLevelEmphasis" 11.692798
#     7. "GrayLevelNonUniformityNormalized"  8.402790
#     8.                "GrayLevelVariance"  1.551008
#     9.          "LowGrayLevelRunEmphasis"  0.800106
#    10.         "HighGrayLevelRunEmphasis"  0.791308
#    11. "RunLengthNonUniformityNormalized"  0.522662
#    12.                  "LongRunEmphasis"  0.472166
#    13.           "RunLengthNonUniformity"  0.062404
#    14.                    "RunPercentage"  0.032645
#    15.                      "RunVariance"  0.019129
#    16.                 "ShortRunEmphasis"  0.010601
#
#
#
# Loss: BINOMIAL_LOG_LIKELIHOOD
# Validation loss value: 0.546242
# Number of trees per iteration: 1
# Node format: NOT_SET
# Number of trees: 30
# Total number of nodes: 812
#
# Number of nodes by tree:
# Count: 30 Average: 27.0667 StdDev: 3.32599
# Min: 19 Max: 31 Ignored: 0
# ----------------------------------------------
# [ 19, 20) 1   3.33%   3.33% #
# [ 20, 21) 0   0.00%   3.33%
# [ 21, 22) 0   0.00%   3.33%
# [ 22, 23) 0   0.00%   3.33%
# [ 23, 24) 5  16.67%  20.00% ######
# [ 24, 25) 0   0.00%  20.00%
# [ 25, 26) 8  26.67%  46.67% ##########
# [ 26, 27) 0   0.00%  46.67%
# [ 27, 28) 1   3.33%  50.00% #
# [ 28, 29) 0   0.00%  50.00%
# [ 29, 30) 7  23.33%  73.33% #########
# [ 30, 31) 0   0.00%  73.33%
# [ 31, 31] 8  26.67% 100.00% ##########
#
# Depth by leafs:
# Count: 421 Average: 4.16152 StdDev: 0.936229
# Min: 2 Max: 5 Ignored: 0
# ----------------------------------------------
# [ 2, 3)  30   7.13%   7.13% ##
# [ 3, 4)  66  15.68%  22.80% ###
# [ 4, 5) 131  31.12%  53.92% #######
# [ 5, 5] 194  46.08% 100.00% ##########
#
# Number of training obs by leaf:
# Count: 421 Average: 55.5107 StdDev: 168.737
# Min: 5 Max: 698 Ignored: 0
# ----------------------------------------------
# [   5,  39) 384  91.21%  91.21% ##########
# [  39,  74)   6   1.43%  92.64%
# [  74, 109)   0   0.00%  92.64%
# [ 109, 143)   1   0.24%  92.87%
# [ 143, 178)   0   0.00%  92.87%
# [ 178, 213)   0   0.00%  92.87%
# [ 213, 247)   0   0.00%  92.87%
# [ 247, 282)   0   0.00%  92.87%
# [ 282, 317)   0   0.00%  92.87%
# [ 317, 352)   0   0.00%  92.87%
# [ 352, 386)   0   0.00%  92.87%
# [ 386, 421)   0   0.00%  92.87%
# [ 421, 456)   0   0.00%  92.87%
# [ 456, 490)   0   0.00%  92.87%
# [ 490, 525)   1   0.24%  93.11%
# [ 525, 560)   0   0.00%  93.11%
# [ 560, 594)   0   0.00%  93.11%
# [ 594, 629)   0   0.00%  93.11%
# [ 629, 664)  16   3.80%  96.91%
# [ 664, 698]  13   3.09% 100.00%
#
# Attribute in nodes:
# 	60 : RunEntropy [NUMERICAL]
# 	48 : LongRunHighGrayLevelEmphasis [NUMERICAL]
# 	42 : ShortRunHighGrayLevelEmphasis [NUMERICAL]
# 	40 : GrayLevelVariance [NUMERICAL]
# 	39 : LongRunLowGrayLevelEmphasis [NUMERICAL]
# 	35 : GrayLevelNonUniformity [NUMERICAL]
# 	28 : ShortRunLowGrayLevelEmphasis [NUMERICAL]
# 	23 : GrayLevelNonUniformityNormalized [NUMERICAL]
# 	20 : LowGrayLevelRunEmphasis [NUMERICAL]
# 	19 : HighGrayLevelRunEmphasis [NUMERICAL]
# 	9 : RunVariance [NUMERICAL]
# 	8 : RunLengthNonUniformityNormalized [NUMERICAL]
# 	7 : RunLengthNonUniformity [NUMERICAL]
# 	5 : ShortRunEmphasis [NUMERICAL]
# 	4 : RunPercentage [NUMERICAL]
# 	4 : LongRunEmphasis [NUMERICAL]
#
# Attribute in nodes with depth <= 0:
# 	15 : ShortRunHighGrayLevelEmphasis [NUMERICAL]
# 	15 : LongRunHighGrayLevelEmphasis [NUMERICAL]
#
# Attribute in nodes with depth <= 1:
# 	27 : ShortRunHighGrayLevelEmphasis [NUMERICAL]
# 	20 : RunEntropy [NUMERICAL]
# 	15 : LongRunHighGrayLevelEmphasis [NUMERICAL]
# 	8 : GrayLevelNonUniformity [NUMERICAL]
# 	6 : LowGrayLevelRunEmphasis [NUMERICAL]
# 	5 : ShortRunLowGrayLevelEmphasis [NUMERICAL]
# 	5 : LongRunLowGrayLevelEmphasis [NUMERICAL]
# 	2 : HighGrayLevelRunEmphasis [NUMERICAL]
# 	2 : GrayLevelNonUniformityNormalized [NUMERICAL]
#
# Attribute in nodes with depth <= 2:
# 	38 : ShortRunHighGrayLevelEmphasis [NUMERICAL]
# 	26 : LongRunHighGrayLevelEmphasis [NUMERICAL]
# 	25 : RunEntropy [NUMERICAL]
# 	19 : LongRunLowGrayLevelEmphasis [NUMERICAL]
# 	16 : GrayLevelVariance [NUMERICAL]
# 	12 : ShortRunLowGrayLevelEmphasis [NUMERICAL]
# 	11 : GrayLevelNonUniformity [NUMERICAL]
# 	8 : HighGrayLevelRunEmphasis [NUMERICAL]
# 	7 : LowGrayLevelRunEmphasis [NUMERICAL]
# 	7 : GrayLevelNonUniformityNormalized [NUMERICAL]
# 	6 : RunVariance [NUMERICAL]
# 	2 : RunLengthNonUniformity [NUMERICAL]
# 	1 : ShortRunEmphasis [NUMERICAL]
# 	1 : RunPercentage [NUMERICAL]
# 	1 : RunLengthNonUniformityNormalized [NUMERICAL]
#
# Attribute in nodes with depth <= 3:
# 	47 : RunEntropy [NUMERICAL]
# 	40 : ShortRunHighGrayLevelEmphasis [NUMERICAL]
# 	34 : LongRunLowGrayLevelEmphasis [NUMERICAL]
# 	33 : GrayLevelVariance [NUMERICAL]
# 	30 : LongRunHighGrayLevelEmphasis [NUMERICAL]
# 	25 : ShortRunLowGrayLevelEmphasis [NUMERICAL]
# 	24 : GrayLevelNonUniformity [NUMERICAL]
# 	17 : GrayLevelNonUniformityNormalized [NUMERICAL]
# 	11 : LowGrayLevelRunEmphasis [NUMERICAL]
# 	11 : HighGrayLevelRunEmphasis [NUMERICAL]
# 	9 : RunVariance [NUMERICAL]
# 	6 : RunLengthNonUniformityNormalized [NUMERICAL]
# 	4 : RunLengthNonUniformity [NUMERICAL]
# 	2 : RunPercentage [NUMERICAL]
# 	1 : ShortRunEmphasis [NUMERICAL]
#
# Attribute in nodes with depth <= 5:
# 	60 : RunEntropy [NUMERICAL]
# 	48 : LongRunHighGrayLevelEmphasis [NUMERICAL]
# 	42 : ShortRunHighGrayLevelEmphasis [NUMERICAL]
# 	40 : GrayLevelVariance [NUMERICAL]
# 	39 : LongRunLowGrayLevelEmphasis [NUMERICAL]
# 	35 : GrayLevelNonUniformity [NUMERICAL]
# 	28 : ShortRunLowGrayLevelEmphasis [NUMERICAL]
# 	23 : GrayLevelNonUniformityNormalized [NUMERICAL]
# 	20 : LowGrayLevelRunEmphasis [NUMERICAL]
# 	19 : HighGrayLevelRunEmphasis [NUMERICAL]
# 	9 : RunVariance [NUMERICAL]
# 	8 : RunLengthNonUniformityNormalized [NUMERICAL]
# 	7 : RunLengthNonUniformity [NUMERICAL]
# 	5 : ShortRunEmphasis [NUMERICAL]
# 	4 : RunPercentage [NUMERICAL]
# 	4 : LongRunEmphasis [NUMERICAL]
#
# Condition type in nodes:
# 	391 : HigherCondition
# Condition type in nodes with depth <= 0:
# 	30 : HigherCondition
# Condition type in nodes with depth <= 1:
# 	90 : HigherCondition
# Condition type in nodes with depth <= 2:
# 	180 : HigherCondition
# Condition type in nodes with depth <= 3:
# 	294 : HigherCondition
# Condition type in nodes with depth <= 5:
# 	391 : HigherCondition
#
# Training logs:
# Number of iteration to final model: 30
# 	Iter:1 train-loss:1.201783 valid-loss:1.247187  train-accuracy:0.991743 valid-accuracy:0.881837
# 	Iter:2 train-loss:1.048468 valid-loss:1.171735  train-accuracy:0.996560 valid-accuracy:0.777314
# 	Iter:3 train-loss:0.920716 valid-loss:1.115977  train-accuracy:0.995184 valid-accuracy:0.777314
# 	Iter:4 train-loss:0.812702 valid-loss:1.076187  train-accuracy:0.996560 valid-accuracy:0.777314
# 	Iter:5 train-loss:0.720532 valid-loss:1.048308  train-accuracy:0.995184 valid-accuracy:0.777314
# 	Iter:6 train-loss:0.641126 valid-loss:1.030839  train-accuracy:0.996560 valid-accuracy:0.777314
# 	Iter:16 train-loss:0.225486 valid-loss:0.929244  train-accuracy:0.996560 valid-accuracy:0.777314
# 	Iter:26 train-loss:0.089138 valid-loss:0.611444  train-accuracy:0.997936 valid-accuracy:0.888657
# 	Iter:36 train-loss:0.037311 valid-loss:0.612316  train-accuracy:0.997936 valid-accuracy:0.888657
# 	Iter:46 train-loss:0.015745 valid-loss:0.706086  train-accuracy:1.000000 valid-accuracy:0.888657
# 	Iter:56 train-loss:0.006885 valid-loss:0.830597  train-accuracy:1.000000 valid-accuracy:0.888657

# %%
# Model features
model.make_inspector().features()
# Out:
# ["GrayLevelNonUniformity" (1; #0),
#  "GrayLevelNonUniformityNormalized" (1; #1),
#  "GrayLevelVariance" (1; #2),
#  "HighGrayLevelRunEmphasis" (1; #3),
#  "LongRunEmphasis" (1; #4),
#  "LongRunHighGrayLevelEmphasis" (1; #5),
#  "LongRunLowGrayLevelEmphasis" (1; #6),
#  "LowGrayLevelRunEmphasis" (1; #7),
#  "RunEntropy" (1; #8),
#  "RunLengthNonUniformity" (1; #9),
#  "RunLengthNonUniformityNormalized" (1; #10),
#  "RunPercentage" (1; #11),
#  "RunVariance" (1; #12),
#  "ShortRunEmphasis" (1; #13),
#  "ShortRunHighGrayLevelEmphasis" (1; #14),
#  "ShortRunLowGrayLevelEmphasis" (1; #15)]

# %%
# Feature importance
model.make_inspector().variable_importances()
# Out:
# {'INV_MEAN_MIN_DEPTH': [("ShortRunHighGrayLevelEmphasis" (1; #14),
#    0.44929150186244776),
#   ("LongRunHighGrayLevelEmphasis" (1; #5), 0.3414102138555645),
#   ("RunEntropy" (1; #8), 0.24269390231570429),
#   ("LongRunLowGrayLevelEmphasis" (1; #6), 0.23379017331944582),
#   ("ShortRunLowGrayLevelEmphasis" (1; #15), 0.22343145288757524),
#   ("GrayLevelVariance" (1; #2), 0.22019606591094698),
#   ("LowGrayLevelRunEmphasis" (1; #7), 0.21888402554181488),
#   ("GrayLevelNonUniformity" (1; #0), 0.21707583739190936),
#   ("GrayLevelNonUniformityNormalized" (1; #1), 0.20712317854416307),
#   ("HighGrayLevelRunEmphasis" (1; #3), 0.2064274813200773),
#   ("RunVariance" (1; #12), 0.1998263413937887),
#   ("RunLengthNonUniformityNormalized" (1; #10), 0.19789850633746406),
#   ("RunLengthNonUniformity" (1; #9), 0.19752431369948087),
#   ("ShortRunEmphasis" (1; #13), 0.19616390584132515),
#   ("RunPercentage" (1; #11), 0.19602311229772773),
#   ("LongRunEmphasis" (1; #4), 0.19542761423209354)],
#  'NUM_AS_ROOT': [("LongRunHighGrayLevelEmphasis" (1; #5), 15.0),
#   ("ShortRunHighGrayLevelEmphasis" (1; #14), 15.0)],
#  'SUM_SCORE': [("LongRunHighGrayLevelEmphasis" (1; #5), 846.8179317801515),
#   ("ShortRunHighGrayLevelEmphasis" (1; #14), 56.791389229482746),
#   ("RunEntropy" (1; #8), 45.16316950425087),
#   ("GrayLevelNonUniformity" (1; #0), 33.89998748139284),
#   ("ShortRunLowGrayLevelEmphasis" (1; #15), 18.503049851315414),
#   ("LongRunLowGrayLevelEmphasis" (1; #6), 11.692798142437093),
#   ("GrayLevelNonUniformityNormalized" (1; #1), 8.402789643434394),
#   ("GrayLevelVariance" (1; #2), 1.5510081552577362),
#   ("LowGrayLevelRunEmphasis" (1; #7), 0.8001056298630909),
#   ("HighGrayLevelRunEmphasis" (1; #3), 0.7913082961557294),
#   ("RunLengthNonUniformityNormalized" (1; #10), 0.5226621111577466),
#   ("LongRunEmphasis" (1; #4), 0.4721664448037486),
#   ("RunLengthNonUniformity" (1; #9), 0.062403591049704124),
#   ("RunPercentage" (1; #11), 0.03264529137154817),
#   ("RunVariance" (1; #12), 0.01912878210822439),
#   ("ShortRunEmphasis" (1; #13), 0.010600713606612128)],
#  'NUM_NODES': [("RunEntropy" (1; #8), 60.0),
#   ("LongRunHighGrayLevelEmphasis" (1; #5), 48.0),
#   ("ShortRunHighGrayLevelEmphasis" (1; #14), 42.0),
#   ("GrayLevelVariance" (1; #2), 40.0),
#   ("LongRunLowGrayLevelEmphasis" (1; #6), 39.0),
#   ("GrayLevelNonUniformity" (1; #0), 35.0),
#   ("ShortRunLowGrayLevelEmphasis" (1; #15), 28.0),
#   ("GrayLevelNonUniformityNormalized" (1; #1), 23.0),
#   ("LowGrayLevelRunEmphasis" (1; #7), 20.0),
#   ("HighGrayLevelRunEmphasis" (1; #3), 19.0),
#   ("RunVariance" (1; #12), 9.0),
#   ("RunLengthNonUniformityNormalized" (1; #10), 8.0),
#   ("RunLengthNonUniformity" (1; #9), 7.0),
#   ("ShortRunEmphasis" (1; #13), 5.0),
#   ("LongRunEmphasis" (1; #4), 4.0),
#   ("RunPercentage" (1; #11), 4.0)]}

# %%
# Model self evaluation
model.make_inspector().evaluation()
# Out:
# Evaluation(num_examples=None, accuracy=0.8886569142341614, loss=0.5462416410446167, rmse=None, ndcg=None, aucs=None, auuc=None, qini=None)

# %%
logs = model.make_inspector().training_logs()

plt.figure(figsize=(12, 4))
plt.subplot(1, 2, 1)
plt.plot([log.num_trees for log in logs], [log.evaluation.accuracy for log in logs])
plt.xlabel("Number of trees")
plt.ylabel("Accuracy (out-of-bag)")
plt.subplot(1, 2, 2)
plt.plot([log.num_trees for log in logs], [log.evaluation.loss for log in logs])
plt.xlabel("Number of trees")
plt.ylabel("Logloss (out-of-bag)")
plt.show()

# %% [markdown]
# Calculate the score of our hold-out validation dataset

# %%
predictions = model.predict(val_ds)
y_true      = validation_data["label"]

from sklearn.metrics import roc_auc_score
ROC_AUC = roc_auc_score(y_true, predictions)
print("The ROC AUC score is %.5f" % ROC_AUC )
# Out:
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 60ms/step
# The ROC AUC score is 0.98718

# %%
# Compute binary classification metrics with sklearn
import numpy as np
from sklearn.metrics import (
    accuracy_score,
    precision_score,
    recall_score,
    f1_score,
    roc_auc_score,
    average_precision_score,
    confusion_matrix,
    classification_report,
    matthews_corrcoef,
    log_loss,
    brier_score_loss,
)

# Get predictions (probabilities or class labels)
preds = model.predict(test_ds)
# If model outputs probabilities, convert to labels by threshold 0.5
if preds.ndim == 2:
    # For TFDF classification, preds may be class probabilities with shape (N, 2)
    if preds.shape[1] == 2:
        pos_probs = preds[:, 1]
    else:
        # If single-probability column (positive class)
        pos_probs = preds[:, -1]
    y_pred = (pos_probs >= 0.5).astype(int)
else:
    # Already class labels
    y_pred = preds.astype(int)
    pos_probs = None

# Ground truth labels (must be 0/1 integers)
y_true = test_data["label"].astype(int).to_numpy()

# Core metrics
metrics = {}
metrics["accuracy"] = accuracy_score(y_true, y_pred)
metrics["precision"] = precision_score(y_true, y_pred, zero_division=0)
metrics["recall"] = recall_score(y_true, y_pred, zero_division=0)
metrics["f1"] = f1_score(y_true, y_pred, zero_division=0)
metrics["mcc"] = matthews_corrcoef(y_true, y_pred)

# Probabilistic metrics (only if we have probabilities)
if pos_probs is not None:
    metrics["roc_auc"] = roc_auc_score(y_true, pos_probs)
    metrics["pr_auc"] = average_precision_score(y_true, pos_probs)
    metrics["log_loss"] = log_loss(y_true, pos_probs, labels=[0,1])
    metrics["brier_score"] = brier_score_loss(y_true, pos_probs)

# Confusion matrix and detailed report
cm = confusion_matrix(y_true, y_pred, labels=[0,1])
report = classification_report(y_true, y_pred, digits=4)

print("Sklearn binary metrics:")
for k, v in metrics.items():
    print(f"{k}: {v:.4f}")
print("\nConfusion matrix:\n", cm)
print("\nClassification report:\n", report)
# Out:
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 64ms/step
# Sklearn binary metrics:
# accuracy: 0.9918
# precision: 0.9474
# recall: 0.9474
# f1: 0.9474
# mcc: 0.9429
# roc_auc: 0.9953
# pr_auc: 0.9709
# log_loss: 0.0534
# brier_score: 0.0088
#
# Confusion matrix:
#  [[224   1]
#  [  1  18]]
#
# Classification report:
#                precision    recall  f1-score   support
#
#            0     0.9956    0.9956    0.9956       225
#            1     0.9474    0.9474    0.9474        19
#
#     accuracy                         0.9918       244
#    macro avg     0.9715    0.9715    0.9715       244
# weighted avg     0.9918    0.9918    0.9918       244
