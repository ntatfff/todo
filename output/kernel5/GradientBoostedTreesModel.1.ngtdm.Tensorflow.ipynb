# %%
# Import packages and modules
import numpy  as np
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow_decision_forests as tfdf

from sklearn.model_selection import train_test_split
# Out:
# 2026-08-15 05:04:45.653766: I tensorflow/core/util/port.cc:113] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2026-08-15 05:04:46.007608: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2026-08-15 05:04:51.406542: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
# Check the version of TensorFlow Decision Forests
print("Found TensorFlow Decision Forests v" + tfdf.__version__)
# Out:
# Found TensorFlow Decision Forests v1.9.1

# %%
datasetPath = 'dataset/firstorder/kernel5/dataset.csv'

# %%
# Parameters
datasetPath = "dataset/ngtdm/kernel5/1.dataset.csv"

# %%
# train/validation/test = 70/10/20
dataset = pd.read_csv(datasetPath)

train_data, temp_data = train_test_split(dataset, test_size=0.3, random_state=42)
validation_data, test_data = train_test_split(temp_data, test_size=2/3, random_state=42)

# %%
from sklearn.utils.class_weight import compute_class_weight

# tinh class weight tren tap train
classes = np.array([0, 1])
weights = compute_class_weight(class_weight="balanced", classes=classes, y=train_data["label"])
class_weight = {0: weights[0], 1: weights[1]}

# gan sample_weight cho tung dong
train_data["sample_weight"] = train_data["label"].map(class_weight)
validation_data["sample_weight"] = validation_data["label"].map(class_weight)
test_data["sample_weight"] = test_data["label"].map(class_weight)

# Convert the dataset into a TensorFlow dataset.
train_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    train_data, label="label", weight="sample_weight"
)         
val_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    validation_data, label="label", weight="sample_weight"
)
test_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    test_data, label="label", weight="sample_weight"
)
# Out:
# 2026-08-15 05:05:04.404156: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:984] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2026-08-15 05:05:04.405398: W tensorflow/core/common_runtime/gpu/gpu_device.cc:2251] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...

# %%
import keras

# %%
# %%time

# Train a Gradient Boosted Trees model.
model = tfdf.keras.GradientBoostedTreesModel()

# Add evaluation metrics
model.compile(
    metrics=["accuracy"]
)
model.fit(x=train_ds)

# # Train a Gradient Boosted Trees model.
# model = tfdf.keras.GradientBoostedTreesModel(num_trees=1500)
# model.fit(train_ds)
# Out:
# Use /tmp/tmpqv3jivra as temporary training directory
# Reading training dataset...
# [WARNING 26-08-15 05:05:04.5380 UTC gradient_boosted_trees.cc:1840] "goss_alpha" set but "sampling_method" not equal to "GOSS".
# [WARNING 26-08-15 05:05:04.5382 UTC gradient_boosted_trees.cc:1851] "goss_beta" set but "sampling_method" not equal to "GOSS".
# [WARNING 26-08-15 05:05:04.5382 UTC gradient_boosted_trees.cc:1865] "selective_gradient_boosting_ratio" set but "sampling_method" not equal to "SELGB".
# Training dataset read in 0:00:02.571538. Found 849 examples.
# Training model...
# Model trained in 0:00:00.254488
# Compiling model...
# [INFO 26-08-15 05:05:07.3931 UTC kernel.cc:1233] Loading model from path /tmp/tmpqv3jivra/model/ with prefix 37fb786739174d7c
# [INFO 26-08-15 05:05:07.3962 UTC quick_scorer_extended.cc:911] The binary was compiled without AVX2 support, but your CPU supports it. Enable it for faster model inference.
# [INFO 26-08-15 05:05:07.3964 UTC abstract_model.cc:1362] Engine "GradientBoostedTreesQuickScorerExtended" built
# [INFO 26-08-15 05:05:07.3964 UTC kernel.cc:1061] Use fast generic engine
# Model compiled.
# CPU times: user 5.51 s, sys: 322 ms, total: 5.84 s
# Wall time: 5.97 s

# %%
# Evaluate the model
evaluate = model.evaluate(val_ds, return_dict=True)
print()

for name, value in evaluate.items():
    print(f"{name}: {value:.4f}")
# Out:
# WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 1/1 [==============================] - ETA: 0s - loss: 0.0000e+00 - accuracy: 0.9917
# 1/1 [==============================] - 3s 3s/step - loss: 0.0000e+00 - accuracy: 0.9917
# loss: 0.0000
# accuracy: 0.9917

# %%
# Model Summary
model.summary()
# Out:
# Model: "gradient_boosted_trees_model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
# =================================================================
# Total params: 1 (1.00 Byte)
# Trainable params: 0 (0.00 Byte)
# Non-trainable params: 1 (1.00 Byte)
# _________________________________________________________________
# Type: "GRADIENT_BOOSTED_TREES"
# Task: CLASSIFICATION
# Label: "__LABEL"
#
# Input Features (5):
# 	Busyness
# 	Coarseness
# 	Complexity
# 	Contrast
# 	Strength
#
# Trained with weights
#
# Variable Importance: INV_MEAN_MIN_DEPTH:
#     1.   "Busyness"  0.777890 ################
#     2. "Coarseness"  0.300675 ##
#     3.   "Strength"  0.243807
#     4. "Complexity"  0.217399
#     5.   "Contrast"  0.211468
#
# Variable Importance: NUM_AS_ROOT:
#     1.   "Busyness" 61.000000 ################
#     2. "Coarseness"  7.000000
#
# Variable Importance: NUM_NODES:
#     1.   "Busyness" 334.000000 ################
#     2. "Coarseness" 215.000000 ######
#     3.   "Strength" 177.000000 ###
#     4. "Complexity" 153.000000 #
#     5.   "Contrast" 136.000000
#
# Variable Importance: SUM_SCORE:
#     1.   "Busyness" 902.501870 ################
#     2. "Complexity" 50.269502
#     3. "Coarseness" 47.100486
#     4.   "Contrast" 14.795114
#     5.   "Strength" 13.756675
#
#
#
# Loss: BINOMIAL_LOG_LIKELIHOOD
# Validation loss value: 0.0924013
# Number of trees per iteration: 1
# Node format: NOT_SET
# Number of trees: 68
# Total number of nodes: 2098
#
# Number of nodes by tree:
# Count: 68 Average: 30.8529 StdDev: 5.74268
# Min: 17 Max: 43 Ignored: 0
# ----------------------------------------------
# [ 17, 18)  1   1.47%   1.47% #
# [ 18, 19)  0   0.00%   1.47%
# [ 19, 21)  0   0.00%   1.47%
# [ 21, 22)  4   5.88%   7.35% ####
# [ 22, 23)  0   0.00%   7.35%
# [ 23, 25)  6   8.82%  16.18% #####
# [ 25, 26)  4   5.88%  22.06% ####
# [ 26, 27)  0   0.00%  22.06%
# [ 27, 29)  6   8.82%  30.88% #####
# [ 29, 30)  7  10.29%  41.18% ######
# [ 30, 31)  0   0.00%  41.18%
# [ 31, 33)  8  11.76%  52.94% #######
# [ 33, 34) 11  16.18%  69.12% ##########
# [ 34, 35)  0   0.00%  69.12%
# [ 35, 37)  9  13.24%  82.35% ########
# [ 37, 38)  4   5.88%  88.24% ####
# [ 38, 39)  0   0.00%  88.24%
# [ 39, 41)  5   7.35%  95.59% #####
# [ 41, 42)  2   2.94%  98.53% ##
# [ 42, 43]  1   1.47% 100.00% #
#
# Depth by leafs:
# Count: 1083 Average: 4.31948 StdDev: 0.886681
# Min: 2 Max: 5 Ignored: 0
# ----------------------------------------------
# [ 2, 3)  48   4.43%   4.43% #
# [ 3, 4) 164  15.14%  19.58% ###
# [ 4, 5) 265  24.47%  44.04% ####
# [ 5, 5] 606  55.96% 100.00% ##########
#
# Number of training obs by leaf:
# Count: 1083 Average: 48.9123 StdDev: 140.279
# Min: 5 Max: 687 Ignored: 0
# ----------------------------------------------
# [   5,  39) 957  88.37%  88.37% ##########
# [  39,  73)  35   3.23%  91.60%
# [  73, 107)   9   0.83%  92.43%
# [ 107, 141)   7   0.65%  93.07%
# [ 141, 175)   0   0.00%  93.07%
# [ 175, 209)   5   0.46%  93.54%
# [ 209, 244)   0   0.00%  93.54%
# [ 244, 278)   0   0.00%  93.54%
# [ 278, 312)   2   0.18%  93.72%
# [ 312, 346)   2   0.18%  93.91%
# [ 346, 380)   2   0.18%  94.09%
# [ 380, 414)   1   0.09%  94.18%
# [ 414, 448)   2   0.18%  94.37%
# [ 448, 483)   4   0.37%  94.74%
# [ 483, 517)   4   0.37%  95.11%
# [ 517, 551)   5   0.46%  95.57%
# [ 551, 585)   5   0.46%  96.03%
# [ 585, 619)  18   1.66%  97.69%
# [ 619, 653)  15   1.39%  99.08%
# [ 653, 687]  10   0.92% 100.00%
#
# Attribute in nodes:
# 	334 : Busyness [NUMERICAL]
# 	215 : Coarseness [NUMERICAL]
# 	177 : Strength [NUMERICAL]
# 	153 : Complexity [NUMERICAL]
# 	136 : Contrast [NUMERICAL]
#
# Attribute in nodes with depth <= 0:
# 	61 : Busyness [NUMERICAL]
# 	7 : Coarseness [NUMERICAL]
#
# Attribute in nodes with depth <= 1:
# 	106 : Busyness [NUMERICAL]
# 	66 : Coarseness [NUMERICAL]
# 	16 : Strength [NUMERICAL]
# 	10 : Complexity [NUMERICAL]
# 	6 : Contrast [NUMERICAL]
#
# Attribute in nodes with depth <= 2:
# 	182 : Busyness [NUMERICAL]
# 	118 : Coarseness [NUMERICAL]
# 	59 : Strength [NUMERICAL]
# 	38 : Complexity [NUMERICAL]
# 	31 : Contrast [NUMERICAL]
#
# Attribute in nodes with depth <= 3:
# 	250 : Busyness [NUMERICAL]
# 	161 : Coarseness [NUMERICAL]
# 	110 : Strength [NUMERICAL]
# 	101 : Complexity [NUMERICAL]
# 	90 : Contrast [NUMERICAL]
#
# Attribute in nodes with depth <= 5:
# 	334 : Busyness [NUMERICAL]
# 	215 : Coarseness [NUMERICAL]
# 	177 : Strength [NUMERICAL]
# 	153 : Complexity [NUMERICAL]
# 	136 : Contrast [NUMERICAL]
#
# Condition type in nodes:
# 	1015 : HigherCondition
# Condition type in nodes with depth <= 0:
# 	68 : HigherCondition
# Condition type in nodes with depth <= 1:
# 	204 : HigherCondition
# Condition type in nodes with depth <= 2:
# 	428 : HigherCondition
# Condition type in nodes with depth <= 3:
# 	712 : HigherCondition
# Condition type in nodes with depth <= 5:
# 	1015 : HigherCondition
#
# Training logs:
# Number of iteration to final model: 68
# 	Iter:1 train-loss:1.204859 valid-loss:1.208236  train-accuracy:0.987593 valid-accuracy:0.978131
# 	Iter:2 train-loss:1.056309 valid-loss:1.062426  train-accuracy:0.987593 valid-accuracy:0.978131
# 	Iter:3 train-loss:0.932540 valid-loss:0.941314  train-accuracy:0.987593 valid-accuracy:0.978131
# 	Iter:4 train-loss:0.828054 valid-loss:0.839413  train-accuracy:0.987593 valid-accuracy:0.978131
# 	Iter:5 train-loss:0.738946 valid-loss:0.752825  train-accuracy:0.987593 valid-accuracy:0.978131
# 	Iter:6 train-loss:0.662342 valid-loss:0.678735  train-accuracy:0.987593 valid-accuracy:0.978131
# 	Iter:16 train-loss:0.247426 valid-loss:0.263679  train-accuracy:0.991729 valid-accuracy:0.985421
# 	Iter:26 train-loss:0.110240 valid-loss:0.147259  train-accuracy:0.994486 valid-accuracy:0.985421
# 	Iter:36 train-loss:0.055010 valid-loss:0.107478  train-accuracy:0.997243 valid-accuracy:0.985421
# 	Iter:46 train-loss:0.031340 valid-loss:0.099656  train-accuracy:0.997243 valid-accuracy:0.992710
# 	Iter:56 train-loss:0.017416 valid-loss:0.096934  train-accuracy:0.998621 valid-accuracy:0.992710
# 	Iter:66 train-loss:0.010401 valid-loss:0.093207  train-accuracy:1.000000 valid-accuracy:0.992710
# 	Iter:76 train-loss:0.006293 valid-loss:0.094565  train-accuracy:1.000000 valid-accuracy:0.992710
# 	Iter:86 train-loss:0.003941 valid-loss:0.099744  train-accuracy:1.000000 valid-accuracy:0.992710
# 	Iter:96 train-loss:0.002456 valid-loss:0.100272  train-accuracy:1.000000 valid-accuracy:0.992710

# %%
# Model features
model.make_inspector().features()
# Out:
# ["Busyness" (1; #0),
#  "Coarseness" (1; #1),
#  "Complexity" (1; #2),
#  "Contrast" (1; #3),
#  "Strength" (1; #4)]

# %%
# Feature importance
model.make_inspector().variable_importances()
# Out:
# {'INV_MEAN_MIN_DEPTH': [("Busyness" (1; #0), 0.7778901191414552),
#   ("Coarseness" (1; #1), 0.3006754665666458),
#   ("Strength" (1; #4), 0.2438069792513917),
#   ("Complexity" (1; #2), 0.2173989015047501),
#   ("Contrast" (1; #3), 0.2114675693614106)],
#  'SUM_SCORE': [("Busyness" (1; #0), 902.5018700768248),
#   ("Complexity" (1; #2), 50.269501633385936),
#   ("Coarseness" (1; #1), 47.10048631330263),
#   ("Contrast" (1; #3), 14.795114227917553),
#   ("Strength" (1; #4), 13.75667506377232)],
#  'NUM_AS_ROOT': [("Busyness" (1; #0), 61.0), ("Coarseness" (1; #1), 7.0)],
#  'NUM_NODES': [("Busyness" (1; #0), 334.0),
#   ("Coarseness" (1; #1), 215.0),
#   ("Strength" (1; #4), 177.0),
#   ("Complexity" (1; #2), 153.0),
#   ("Contrast" (1; #3), 136.0)]}

# %%
# Model self evaluation
model.make_inspector().evaluation()
# Out:
# Evaluation(num_examples=None, accuracy=0.9927104115486145, loss=0.09240134805440903, rmse=None, ndcg=None, aucs=None, auuc=None, qini=None)

# %%
logs = model.make_inspector().training_logs()

plt.figure(figsize=(12, 4))
plt.subplot(1, 2, 1)
plt.plot([log.num_trees for log in logs], [log.evaluation.accuracy for log in logs])
plt.xlabel("Number of trees")
plt.ylabel("Accuracy (out-of-bag)")
plt.subplot(1, 2, 2)
plt.plot([log.num_trees for log in logs], [log.evaluation.loss for log in logs])
plt.xlabel("Number of trees")
plt.ylabel("Logloss (out-of-bag)")
plt.show()

# %% [markdown]
# Calculate the score of our hold-out validation dataset

# %%
predictions = model.predict(val_ds)
y_true      = validation_data["label"]

from sklearn.metrics import roc_auc_score
ROC_AUC = roc_auc_score(y_true, predictions)
print("The ROC AUC score is %.5f" % ROC_AUC )
# Out:
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 50ms/step
# The ROC AUC score is 1.00000

# %%
# Compute binary classification metrics with sklearn
import numpy as np
from sklearn.metrics import (
    accuracy_score,
    precision_score,
    recall_score,
    f1_score,
    roc_auc_score,
    average_precision_score,
    confusion_matrix,
    classification_report,
    matthews_corrcoef,
    log_loss,
    brier_score_loss,
)

# Get predictions (probabilities or class labels)
preds = model.predict(test_ds)
# If model outputs probabilities, convert to labels by threshold 0.5
if preds.ndim == 2:
    # For TFDF classification, preds may be class probabilities with shape (N, 2)
    if preds.shape[1] == 2:
        pos_probs = preds[:, 1]
    else:
        # If single-probability column (positive class)
        pos_probs = preds[:, -1]
    y_pred = (pos_probs >= 0.5).astype(int)
else:
    # Already class labels
    y_pred = preds.astype(int)
    pos_probs = None

# Ground truth labels (must be 0/1 integers)
y_true = test_data["label"].astype(int).to_numpy()

# Core metrics
metrics = {}
metrics["accuracy"] = accuracy_score(y_true, y_pred)
metrics["precision"] = precision_score(y_true, y_pred, zero_division=0)
metrics["recall"] = recall_score(y_true, y_pred, zero_division=0)
metrics["f1"] = f1_score(y_true, y_pred, zero_division=0)
metrics["mcc"] = matthews_corrcoef(y_true, y_pred)

# Probabilistic metrics (only if we have probabilities)
if pos_probs is not None:
    metrics["roc_auc"] = roc_auc_score(y_true, pos_probs)
    metrics["pr_auc"] = average_precision_score(y_true, pos_probs)
    metrics["log_loss"] = log_loss(y_true, pos_probs, labels=[0,1])
    metrics["brier_score"] = brier_score_loss(y_true, pos_probs)

# Confusion matrix and detailed report
cm = confusion_matrix(y_true, y_pred, labels=[0,1])
report = classification_report(y_true, y_pred, digits=4)

print("Sklearn binary metrics:")
for k, v in metrics.items():
    print(f"{k}: {v:.4f}")
print("\nConfusion matrix:\n", cm)
print("\nClassification report:\n", report)
# Out:
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 56ms/step
# Sklearn binary metrics:
# accuracy: 0.9795
# precision: 0.8462
# recall: 0.7857
# f1: 0.8148
# mcc: 0.8046
# roc_auc: 0.9870
# pr_auc: 0.8982
# log_loss: 0.0801
# brier_score: 0.0198
#
# Confusion matrix:
#  [[228   2]
#  [  3  11]]
#
# Classification report:
#                precision    recall  f1-score   support
#
#            0     0.9870    0.9913    0.9892       230
#            1     0.8462    0.7857    0.8148        14
#
#     accuracy                         0.9795       244
#    macro avg     0.9166    0.8885    0.9020       244
# weighted avg     0.9789    0.9795    0.9792       244
