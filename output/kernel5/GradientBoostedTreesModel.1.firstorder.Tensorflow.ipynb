# %%
# Import packages and modules
import numpy  as np
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow_decision_forests as tfdf

from sklearn.model_selection import train_test_split
# Out:
# 2026-08-15 05:01:41.731060: I tensorflow/core/util/port.cc:113] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2026-08-15 05:01:42.098825: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2026-08-15 05:01:47.900661: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
# Check the version of TensorFlow Decision Forests
print("Found TensorFlow Decision Forests v" + tfdf.__version__)
# Out:
# Found TensorFlow Decision Forests v1.9.1

# %%
datasetPath = 'dataset/firstorder/kernel5/dataset.csv'

# %%
# Parameters
datasetPath = "dataset/firstorder/kernel5/1.dataset.csv"

# %%
# train/validation/test = 70/10/20
dataset = pd.read_csv(datasetPath)

train_data, temp_data = train_test_split(dataset, test_size=0.3, random_state=42)
validation_data, test_data = train_test_split(temp_data, test_size=2/3, random_state=42)

# %%
from sklearn.utils.class_weight import compute_class_weight

# tinh class weight tren tap train
classes = np.array([0, 1])
weights = compute_class_weight(class_weight="balanced", classes=classes, y=train_data["label"])
class_weight = {0: weights[0], 1: weights[1]}

# gan sample_weight cho tung dong
train_data["sample_weight"] = train_data["label"].map(class_weight)
validation_data["sample_weight"] = validation_data["label"].map(class_weight)
test_data["sample_weight"] = test_data["label"].map(class_weight)

# Convert the dataset into a TensorFlow dataset.
train_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    train_data, label="label", weight="sample_weight"
)         
val_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    validation_data, label="label", weight="sample_weight"
)
test_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    test_data, label="label", weight="sample_weight"
)
# Out:
# 2026-08-15 05:02:01.256612: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:984] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2026-08-15 05:02:01.258313: W tensorflow/core/common_runtime/gpu/gpu_device.cc:2251] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...

# %%
import keras

# %%
# %%time

# Train a Gradient Boosted Trees model.
model = tfdf.keras.GradientBoostedTreesModel()

# Add evaluation metrics
model.compile(
    metrics=["accuracy"]
)
model.fit(x=train_ds)

# # Train a Gradient Boosted Trees model.
# model = tfdf.keras.GradientBoostedTreesModel(num_trees=1500)
# model.fit(train_ds)
# Out:
# Use /tmp/tmp0rcg62c6 as temporary training directory
# Reading training dataset...
# [WARNING 26-08-15 05:02:01.4177 UTC gradient_boosted_trees.cc:1840] "goss_alpha" set but "sampling_method" not equal to "GOSS".
# [WARNING 26-08-15 05:02:01.4179 UTC gradient_boosted_trees.cc:1851] "goss_beta" set but "sampling_method" not equal to "GOSS".
# [WARNING 26-08-15 05:02:01.4179 UTC gradient_boosted_trees.cc:1865] "selective_gradient_boosting_ratio" set but "sampling_method" not equal to "SELGB".
# Training dataset read in 0:00:02.715978. Found 849 examples.
# Training model...
# Model trained in 0:00:00.304263
# Compiling model...
# [INFO 26-08-15 05:02:04.4649 UTC kernel.cc:1233] Loading model from path /tmp/tmp0rcg62c6/model/ with prefix 6caaf374799b41fd
# [INFO 26-08-15 05:02:04.4673 UTC quick_scorer_extended.cc:911] The binary was compiled without AVX2 support, but your CPU supports it. Enable it for faster model inference.
# [INFO 26-08-15 05:02:04.4674 UTC abstract_model.cc:1362] Engine "GradientBoostedTreesQuickScorerExtended" built
# [INFO 26-08-15 05:02:04.4674 UTC kernel.cc:1061] Use fast generic engine
# Model compiled.
# CPU times: user 5.89 s, sys: 448 ms, total: 6.34 s
# Wall time: 6.3 s

# %%
# Evaluate the model
evaluate = model.evaluate(val_ds, return_dict=True)
print()

for name, value in evaluate.items():
    print(f"{name}: {value:.4f}")
# Out:
# WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 1/1 [==============================] - ETA: 0s - loss: 0.0000e+00 - accuracy: 0.9835
# 1/1 [==============================] - 3s 3s/step - loss: 0.0000e+00 - accuracy: 0.9835
# loss: 0.0000
# accuracy: 0.9835

# %%
# Model Summary
model.summary()
# Out:
# Model: "gradient_boosted_trees_model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
# =================================================================
# Total params: 1 (1.00 Byte)
# Trainable params: 0 (0.00 Byte)
# Non-trainable params: 1 (1.00 Byte)
# _________________________________________________________________
# Type: "GRADIENT_BOOSTED_TREES"
# Task: CLASSIFICATION
# Label: "__LABEL"
#
# Input Features (18):
# 	10Percentile
# 	90Percentile
# 	Energy
# 	Entropy
# 	InterquartileRange
# 	Kurtosis
# 	Maximum
# 	Mean
# 	MeanAbsoluteDeviation
# 	Median
# 	Minimum
# 	Range
# 	RobustMeanAbsoluteDeviation
# 	RootMeanSquared
# 	Skewness
# 	TotalEnergy
# 	Uniformity
# 	Variance
#
# Trained with weights
#
# Variable Importance: INV_MEAN_MIN_DEPTH:
#     1.                "90Percentile"  0.498431 ################
#     2.                      "Median"  0.252524 ##
#     3.                     "Maximum"  0.237763 #
#     4.                    "Skewness"  0.237116 #
#     5.                    "Kurtosis"  0.223582
#     6.                 "TotalEnergy"  0.223463
#     7.                      "Energy"  0.221935
#     8.                     "Minimum"  0.221293
#     9.                  "Uniformity"  0.215917
#    10.          "InterquartileRange"  0.215524
#    11.             "RootMeanSquared"  0.215367
#    12.                        "Mean"  0.215120
#    13.                     "Entropy"  0.214066
#    14.                "10Percentile"  0.211445
#    15.       "MeanAbsoluteDeviation"  0.211217
#    16. "RobustMeanAbsoluteDeviation"  0.211204
#    17.                       "Range"  0.210961
#    18.                    "Variance"  0.208769
#
# Variable Importance: NUM_AS_ROOT:
#     1.    "90Percentile" 37.000000 ################
#     2.         "Maximum"  7.000000 ##
#     3.          "Median"  5.000000 #
#     4.          "Energy"  3.000000
#     5.            "Mean"  1.000000
#     6. "RootMeanSquared"  1.000000
#     7.     "TotalEnergy"  1.000000
#
# Variable Importance: NUM_NODES:
#     1.                "90Percentile" 121.000000 ################
#     2.                      "Median" 66.000000 ########
#     3.                    "Skewness" 56.000000 #######
#     4.                     "Maximum" 32.000000 ###
#     5.                 "TotalEnergy" 30.000000 ###
#     6.                  "Uniformity" 30.000000 ###
#     7.                     "Minimum" 28.000000 ###
#     8.                    "Kurtosis" 27.000000 ###
#     9.                "10Percentile" 21.000000 ##
#    10.                      "Energy" 21.000000 ##
#    11.                        "Mean" 20.000000 ##
#    12.          "InterquartileRange" 19.000000 #
#    13.             "RootMeanSquared" 19.000000 #
#    14.                     "Entropy" 18.000000 #
#    15.                       "Range" 18.000000 #
#    16.       "MeanAbsoluteDeviation" 14.000000 #
#    17. "RobustMeanAbsoluteDeviation" 11.000000
#    18.                    "Variance"  5.000000
#
# Variable Importance: SUM_SCORE:
#     1.                "90Percentile" 936.060192 ################
#     2.                     "Maximum" 50.328660
#     3.             "RootMeanSquared"  7.508171
#     4.          "InterquartileRange"  6.343193
#     5.                      "Median"  5.788868
#     6.                 "TotalEnergy"  5.098626
#     7.                      "Energy"  3.563445
#     8.                    "Variance"  2.861087
#     9.                    "Skewness"  2.265083
#    10.                        "Mean"  1.632739
#    11. "RobustMeanAbsoluteDeviation"  1.302736
#    12.                "10Percentile"  1.197115
#    13.                     "Minimum"  0.966911
#    14.       "MeanAbsoluteDeviation"  0.838065
#    15.                    "Kurtosis"  0.833348
#    16.                  "Uniformity"  0.805027
#    17.                       "Range"  0.388211
#    18.                     "Entropy"  0.303184
#
#
#
# Loss: BINOMIAL_LOG_LIKELIHOOD
# Validation loss value: 0.110404
# Number of trees per iteration: 1
# Node format: NOT_SET
# Number of trees: 55
# Total number of nodes: 1167
#
# Number of nodes by tree:
# Count: 55 Average: 21.2182 StdDev: 3.63163
# Min: 13 Max: 29 Ignored: 0
# ----------------------------------------------
# [ 13, 14)  1   1.82%   1.82% #
# [ 14, 15)  0   0.00%   1.82%
# [ 15, 16)  5   9.09%  10.91% ###
# [ 16, 17)  0   0.00%  10.91%
# [ 17, 18)  4   7.27%  18.18% ###
# [ 18, 19)  0   0.00%  18.18%
# [ 19, 20)  7  12.73%  30.91% ####
# [ 20, 21)  0   0.00%  30.91%
# [ 21, 22) 16  29.09%  60.00% ##########
# [ 22, 23)  0   0.00%  60.00%
# [ 23, 24) 12  21.82%  81.82% ########
# [ 24, 25)  0   0.00%  81.82%
# [ 25, 26)  5   9.09%  90.91% ###
# [ 26, 27)  0   0.00%  90.91%
# [ 27, 28)  2   3.64%  94.55% #
# [ 28, 29)  0   0.00%  94.55%
# [ 29, 29]  3   5.45% 100.00% ##
#
# Depth by leafs:
# Count: 611 Average: 3.9329 StdDev: 1.114
# Min: 2 Max: 5 Ignored: 0
# ----------------------------------------------
# [ 2, 3)  96  15.71%  15.71% ####
# [ 3, 4) 113  18.49%  34.21% ####
# [ 4, 5) 138  22.59%  56.79% #####
# [ 5, 5] 264  43.21% 100.00% ##########
#
# Number of training obs by leaf:
# Count: 611 Average: 70.1227 StdDev: 186.532
# Min: 5 Max: 702 Ignored: 0
# ----------------------------------------------
# [   5,  39) 531  86.91%  86.91% ##########
# [  39,  74)  14   2.29%  89.20%
# [  74, 109)   4   0.65%  89.85%
# [ 109, 144)   2   0.33%  90.18%
# [ 144, 179)   1   0.16%  90.34%
# [ 179, 214)   2   0.33%  90.67%
# [ 214, 249)   0   0.00%  90.67%
# [ 249, 284)   0   0.00%  90.67%
# [ 284, 319)   2   0.33%  91.00%
# [ 319, 354)   0   0.00%  91.00%
# [ 354, 388)   0   0.00%  91.00%
# [ 388, 423)   2   0.33%  91.33%
# [ 423, 458)   0   0.00%  91.33%
# [ 458, 493)   1   0.16%  91.49%
# [ 493, 528)   3   0.49%  91.98%
# [ 528, 563)   0   0.00%  91.98%
# [ 563, 598)   3   0.49%  92.47%
# [ 598, 633)   4   0.65%  93.13%
# [ 633, 668)   3   0.49%  93.62%
# [ 668, 702]  39   6.38% 100.00% #
#
# Attribute in nodes:
# 	121 : 90Percentile [NUMERICAL]
# 	66 : Median [NUMERICAL]
# 	56 : Skewness [NUMERICAL]
# 	32 : Maximum [NUMERICAL]
# 	30 : Uniformity [NUMERICAL]
# 	30 : TotalEnergy [NUMERICAL]
# 	28 : Minimum [NUMERICAL]
# 	27 : Kurtosis [NUMERICAL]
# 	21 : Energy [NUMERICAL]
# 	21 : 10Percentile [NUMERICAL]
# 	20 : Mean [NUMERICAL]
# 	19 : RootMeanSquared [NUMERICAL]
# 	19 : InterquartileRange [NUMERICAL]
# 	18 : Range [NUMERICAL]
# 	18 : Entropy [NUMERICAL]
# 	14 : MeanAbsoluteDeviation [NUMERICAL]
# 	11 : RobustMeanAbsoluteDeviation [NUMERICAL]
# 	5 : Variance [NUMERICAL]
#
# Attribute in nodes with depth <= 0:
# 	37 : 90Percentile [NUMERICAL]
# 	7 : Maximum [NUMERICAL]
# 	5 : Median [NUMERICAL]
# 	3 : Energy [NUMERICAL]
# 	1 : TotalEnergy [NUMERICAL]
# 	1 : RootMeanSquared [NUMERICAL]
# 	1 : Mean [NUMERICAL]
#
# Attribute in nodes with depth <= 1:
# 	67 : 90Percentile [NUMERICAL]
# 	15 : Median [NUMERICAL]
# 	11 : Kurtosis [NUMERICAL]
# 	8 : Maximum [NUMERICAL]
# 	8 : InterquartileRange [NUMERICAL]
# 	7 : TotalEnergy [NUMERICAL]
# 	7 : Skewness [NUMERICAL]
# 	6 : RobustMeanAbsoluteDeviation [NUMERICAL]
# 	6 : Minimum [NUMERICAL]
# 	6 : Energy [NUMERICAL]
# 	5 : RootMeanSquared [NUMERICAL]
# 	5 : Mean [NUMERICAL]
# 	4 : MeanAbsoluteDeviation [NUMERICAL]
# 	3 : Variance [NUMERICAL]
# 	3 : Range [NUMERICAL]
# 	2 : 10Percentile [NUMERICAL]
# 	1 : Uniformity [NUMERICAL]
# 	1 : Entropy [NUMERICAL]
#
# Attribute in nodes with depth <= 2:
# 	86 : 90Percentile [NUMERICAL]
# 	31 : Skewness [NUMERICAL]
# 	30 : Median [NUMERICAL]
# 	16 : Kurtosis [NUMERICAL]
# 	14 : Minimum [NUMERICAL]
# 	13 : Maximum [NUMERICAL]
# 	12 : TotalEnergy [NUMERICAL]
# 	11 : Mean [NUMERICAL]
# 	11 : InterquartileRange [NUMERICAL]
# 	11 : Entropy [NUMERICAL]
# 	10 : Uniformity [NUMERICAL]
# 	8 : RobustMeanAbsoluteDeviation [NUMERICAL]
# 	8 : Energy [NUMERICAL]
# 	7 : RootMeanSquared [NUMERICAL]
# 	7 : 10Percentile [NUMERICAL]
# 	6 : MeanAbsoluteDeviation [NUMERICAL]
# 	5 : Range [NUMERICAL]
# 	3 : Variance [NUMERICAL]
#
# Attribute in nodes with depth <= 3:
# 	111 : 90Percentile [NUMERICAL]
# 	44 : Skewness [NUMERICAL]
# 	42 : Median [NUMERICAL]
# 	25 : TotalEnergy [NUMERICAL]
# 	21 : Minimum [NUMERICAL]
# 	20 : Maximum [NUMERICAL]
# 	19 : Uniformity [NUMERICAL]
# 	19 : Kurtosis [NUMERICAL]
# 	16 : Mean [NUMERICAL]
# 	16 : InterquartileRange [NUMERICAL]
# 	16 : 10Percentile [NUMERICAL]
# 	15 : Entropy [NUMERICAL]
# 	13 : RootMeanSquared [NUMERICAL]
# 	13 : Energy [NUMERICAL]
# 	11 : Range [NUMERICAL]
# 	10 : RobustMeanAbsoluteDeviation [NUMERICAL]
# 	10 : MeanAbsoluteDeviation [NUMERICAL]
# 	3 : Variance [NUMERICAL]
#
# Attribute in nodes with depth <= 5:
# 	121 : 90Percentile [NUMERICAL]
# 	66 : Median [NUMERICAL]
# 	56 : Skewness [NUMERICAL]
# 	32 : Maximum [NUMERICAL]
# 	30 : Uniformity [NUMERICAL]
# 	30 : TotalEnergy [NUMERICAL]
# 	28 : Minimum [NUMERICAL]
# 	27 : Kurtosis [NUMERICAL]
# 	21 : Energy [NUMERICAL]
# 	21 : 10Percentile [NUMERICAL]
# 	20 : Mean [NUMERICAL]
# 	19 : RootMeanSquared [NUMERICAL]
# 	19 : InterquartileRange [NUMERICAL]
# 	18 : Range [NUMERICAL]
# 	18 : Entropy [NUMERICAL]
# 	14 : MeanAbsoluteDeviation [NUMERICAL]
# 	11 : RobustMeanAbsoluteDeviation [NUMERICAL]
# 	5 : Variance [NUMERICAL]
#
# Condition type in nodes:
# 	556 : HigherCondition
# Condition type in nodes with depth <= 0:
# 	55 : HigherCondition
# Condition type in nodes with depth <= 1:
# 	165 : HigherCondition
# Condition type in nodes with depth <= 2:
# 	289 : HigherCondition
# Condition type in nodes with depth <= 3:
# 	424 : HigherCondition
# Condition type in nodes with depth <= 5:
# 	556 : HigherCondition
#
# Training logs:
# Number of iteration to final model: 55
# 	Iter:1 train-loss:1.201363 valid-loss:1.210232  train-accuracy:0.991740 valid-accuracy:0.993019
# 	Iter:2 train-loss:1.050249 valid-loss:1.062805  train-accuracy:0.992428 valid-accuracy:0.993019
# 	Iter:3 train-loss:0.924312 valid-loss:0.939629  train-accuracy:0.992428 valid-accuracy:0.993019
# 	Iter:4 train-loss:0.817960 valid-loss:0.835444  train-accuracy:0.992428 valid-accuracy:0.993019
# 	Iter:5 train-loss:0.727153 valid-loss:0.746292  train-accuracy:0.992428 valid-accuracy:0.993019
# 	Iter:6 train-loss:0.648796 valid-loss:0.673875  train-accuracy:0.992428 valid-accuracy:0.993019
# 	Iter:16 train-loss:0.240709 valid-loss:0.275292  train-accuracy:0.992428 valid-accuracy:0.993019
# 	Iter:26 train-loss:0.101289 valid-loss:0.190260  train-accuracy:0.994493 valid-accuracy:0.993019
# 	Iter:36 train-loss:0.044876 valid-loss:0.165293  train-accuracy:0.997247 valid-accuracy:0.993019
# 	Iter:46 train-loss:0.021092 valid-loss:0.147420  train-accuracy:0.998623 valid-accuracy:0.993019
# 	Iter:56 train-loss:0.009969 valid-loss:0.123087  train-accuracy:0.999312 valid-accuracy:0.993019
# 	Iter:66 train-loss:0.004771 valid-loss:0.137090  train-accuracy:1.000000 valid-accuracy:0.993019
# 	Iter:76 train-loss:0.002329 valid-loss:0.214570  train-accuracy:1.000000 valid-accuracy:0.883778

# %%
# Model features
model.make_inspector().features()
# Out:
# ["10Percentile" (1; #0),
#  "90Percentile" (1; #1),
#  "Energy" (1; #2),
#  "Entropy" (1; #3),
#  "InterquartileRange" (1; #4),
#  "Kurtosis" (1; #5),
#  "Maximum" (1; #6),
#  "Mean" (1; #7),
#  "MeanAbsoluteDeviation" (1; #8),
#  "Median" (1; #9),
#  "Minimum" (1; #10),
#  "Range" (1; #11),
#  "RobustMeanAbsoluteDeviation" (1; #12),
#  "RootMeanSquared" (1; #13),
#  "Skewness" (1; #14),
#  "TotalEnergy" (1; #15),
#  "Uniformity" (1; #16),
#  "Variance" (1; #17)]

# %%
# Feature importance
model.make_inspector().variable_importances()
# Out:
# {'INV_MEAN_MIN_DEPTH': [("90Percentile" (1; #1), 0.49843083236726815),
#   ("Median" (1; #9), 0.2525242358185316),
#   ("Maximum" (1; #6), 0.23776271996002663),
#   ("Skewness" (1; #14), 0.23711570313871982),
#   ("Kurtosis" (1; #5), 0.22358161415912658),
#   ("TotalEnergy" (1; #15), 0.22346283808199655),
#   ("Energy" (1; #2), 0.22193529349637475),
#   ("Minimum" (1; #10), 0.22129271891374228),
#   ("Uniformity" (1; #16), 0.21591698559590392),
#   ("InterquartileRange" (1; #4), 0.21552368150698115),
#   ("RootMeanSquared" (1; #13), 0.21536663627670047),
#   ("Mean" (1; #7), 0.21511960265901367),
#   ("Entropy" (1; #3), 0.2140657800754547),
#   ("10Percentile" (1; #0), 0.2114448552547212),
#   ("MeanAbsoluteDeviation" (1; #8), 0.21121667788833193),
#   ("RobustMeanAbsoluteDeviation" (1; #12), 0.21120403756289993),
#   ("Range" (1; #11), 0.210961419003409),
#   ("Variance" (1; #17), 0.20876911165150058)],
#  'SUM_SCORE': [("90Percentile" (1; #1), 936.0601916982539),
#   ("Maximum" (1; #6), 50.32865995116701),
#   ("RootMeanSquared" (1; #13), 7.5081712848019535),
#   ("InterquartileRange" (1; #4), 6.3431932465003635),
#   ("Median" (1; #9), 5.7888684688480625),
#   ("TotalEnergy" (1; #15), 5.098625774010275),
#   ("Energy" (1; #2), 3.5634451931807436),
#   ("Variance" (1; #17), 2.8610866426240777),
#   ("Skewness" (1; #14), 2.2650831312684874),
#   ("Mean" (1; #7), 1.6327394415178764),
#   ("RobustMeanAbsoluteDeviation" (1; #12), 1.3027357539074482),
#   ("10Percentile" (1; #0), 1.1971150345858144),
#   ("Minimum" (1; #10), 0.9669113004261417),
#   ("MeanAbsoluteDeviation" (1; #8), 0.8380652464695078),
#   ("Kurtosis" (1; #5), 0.8333475430580168),
#   ("Uniformity" (1; #16), 0.8050273156522518),
#   ("Range" (1; #11), 0.3882109460246698),
#   ("Entropy" (1; #3), 0.30318422375646326)],
#  'NUM_AS_ROOT': [("90Percentile" (1; #1), 37.0),
#   ("Maximum" (1; #6), 7.0),
#   ("Median" (1; #9), 5.0),
#   ("Energy" (1; #2), 3.0),
#   ("Mean" (1; #7), 1.0),
#   ("RootMeanSquared" (1; #13), 1.0),
#   ("TotalEnergy" (1; #15), 1.0)],
#  'NUM_NODES': [("90Percentile" (1; #1), 121.0),
#   ("Median" (1; #9), 66.0),
#   ("Skewness" (1; #14), 56.0),
#   ("Maximum" (1; #6), 32.0),
#   ("TotalEnergy" (1; #15), 30.0),
#   ("Uniformity" (1; #16), 30.0),
#   ("Minimum" (1; #10), 28.0),
#   ("Kurtosis" (1; #5), 27.0),
#   ("10Percentile" (1; #0), 21.0),
#   ("Energy" (1; #2), 21.0),
#   ("Mean" (1; #7), 20.0),
#   ("InterquartileRange" (1; #4), 19.0),
#   ("RootMeanSquared" (1; #13), 19.0),
#   ("Entropy" (1; #3), 18.0),
#   ("Range" (1; #11), 18.0),
#   ("MeanAbsoluteDeviation" (1; #8), 14.0),
#   ("RobustMeanAbsoluteDeviation" (1; #12), 11.0),
#   ("Variance" (1; #17), 5.0)]}

# %%
# Model self evaluation
model.make_inspector().evaluation()
# Out:
# Evaluation(num_examples=None, accuracy=0.9930185079574585, loss=0.11040445417165756, rmse=None, ndcg=None, aucs=None, auuc=None, qini=None)

# %%
logs = model.make_inspector().training_logs()

plt.figure(figsize=(12, 4))
plt.subplot(1, 2, 1)
plt.plot([log.num_trees for log in logs], [log.evaluation.accuracy for log in logs])
plt.xlabel("Number of trees")
plt.ylabel("Accuracy (out-of-bag)")
plt.subplot(1, 2, 2)
plt.plot([log.num_trees for log in logs], [log.evaluation.loss for log in logs])
plt.xlabel("Number of trees")
plt.ylabel("Logloss (out-of-bag)")
plt.show()

# %% [markdown]
# Calculate the score of our hold-out validation dataset

# %%
predictions = model.predict(val_ds)
y_true      = validation_data["label"]

from sklearn.metrics import roc_auc_score
ROC_AUC = roc_auc_score(y_true, predictions)
print("The ROC AUC score is %.5f" % ROC_AUC )
# Out:
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 60ms/step
# The ROC AUC score is 0.99855

# %%
# Compute binary classification metrics with sklearn
import numpy as np
from sklearn.metrics import (
    accuracy_score,
    precision_score,
    recall_score,
    f1_score,
    roc_auc_score,
    average_precision_score,
    confusion_matrix,
    classification_report,
    matthews_corrcoef,
    log_loss,
    brier_score_loss,
)

# Get predictions (probabilities or class labels)
preds = model.predict(test_ds)
# If model outputs probabilities, convert to labels by threshold 0.5
if preds.ndim == 2:
    # For TFDF classification, preds may be class probabilities with shape (N, 2)
    if preds.shape[1] == 2:
        pos_probs = preds[:, 1]
    else:
        # If single-probability column (positive class)
        pos_probs = preds[:, -1]
    y_pred = (pos_probs >= 0.5).astype(int)
else:
    # Already class labels
    y_pred = preds.astype(int)
    pos_probs = None

# Ground truth labels (must be 0/1 integers)
y_true = test_data["label"].astype(int).to_numpy()

# Core metrics
metrics = {}
metrics["accuracy"] = accuracy_score(y_true, y_pred)
metrics["precision"] = precision_score(y_true, y_pred, zero_division=0)
metrics["recall"] = recall_score(y_true, y_pred, zero_division=0)
metrics["f1"] = f1_score(y_true, y_pred, zero_division=0)
metrics["mcc"] = matthews_corrcoef(y_true, y_pred)

# Probabilistic metrics (only if we have probabilities)
if pos_probs is not None:
    metrics["roc_auc"] = roc_auc_score(y_true, pos_probs)
    metrics["pr_auc"] = average_precision_score(y_true, pos_probs)
    metrics["log_loss"] = log_loss(y_true, pos_probs, labels=[0,1])
    metrics["brier_score"] = brier_score_loss(y_true, pos_probs)

# Confusion matrix and detailed report
cm = confusion_matrix(y_true, y_pred, labels=[0,1])
report = classification_report(y_true, y_pred, digits=4)

print("Sklearn binary metrics:")
for k, v in metrics.items():
    print(f"{k}: {v:.4f}")
print("\nConfusion matrix:\n", cm)
print("\nClassification report:\n", report)
# Out:
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 71ms/step
# Sklearn binary metrics:
# accuracy: 0.9918
# precision: 1.0000
# recall: 0.8667
# f1: 0.9286
# mcc: 0.9269
# roc_auc: 0.9927
# pr_auc: 0.9583
# log_loss: 0.0349
# brier_score: 0.0069
#
# Confusion matrix:
#  [[229   0]
#  [  2  13]]
#
# Classification report:
#                precision    recall  f1-score   support
#
#            0     0.9913    1.0000    0.9957       229
#            1     1.0000    0.8667    0.9286        15
#
#     accuracy                         0.9918       244
#    macro avg     0.9957    0.9333    0.9621       244
# weighted avg     0.9919    0.9918    0.9915       244
