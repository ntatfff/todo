# %%
# Import packages and modules
import numpy  as np
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow_decision_forests as tfdf

from sklearn.model_selection import train_test_split
# Out:
# 2026-08-15 05:16:53.328538: I tensorflow/core/util/port.cc:113] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2026-08-15 05:16:53.682971: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2026-08-15 05:16:58.385382: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
# Check the version of TensorFlow Decision Forests
print("Found TensorFlow Decision Forests v" + tfdf.__version__)
# Out:
# Found TensorFlow Decision Forests v1.9.1

# %%
datasetPath = 'dataset/firstorder/kernel5/dataset.csv'

# %%
# Parameters
datasetPath = "dataset/glcm/kernel5/1.dataset.csv"

# %%
# train/validation/test = 70/10/20
dataset = pd.read_csv(datasetPath)

train_data, temp_data = train_test_split(dataset, test_size=0.3, random_state=42)
validation_data, test_data = train_test_split(temp_data, test_size=2/3, random_state=42)

# %%
from sklearn.utils.class_weight import compute_class_weight

# tinh class weight tren tap train
classes = np.array([0, 1])
weights = compute_class_weight(class_weight="balanced", classes=classes, y=train_data["label"])
class_weight = {0: weights[0], 1: weights[1]}

# gan sample_weight cho tung dong
train_data["sample_weight"] = train_data["label"].map(class_weight)
validation_data["sample_weight"] = validation_data["label"].map(class_weight)
test_data["sample_weight"] = test_data["label"].map(class_weight)

# Convert the dataset into a TensorFlow dataset.
train_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    train_data, label="label", weight="sample_weight"
)         
val_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    validation_data, label="label", weight="sample_weight"
)
test_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    test_data, label="label", weight="sample_weight"
)
# Out:
# 2026-08-15 05:17:12.081908: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:984] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2026-08-15 05:17:12.083759: W tensorflow/core/common_runtime/gpu/gpu_device.cc:2251] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...

# %%
import keras

# %%
# %%time

# Train a Random Forest model.
model = tfdf.keras.RandomForestModel()

# Add evaluation metrics
model.compile(
    metrics=["accuracy"]
)
model.fit(x=train_ds)

# # Train a Gradient Boosted Trees model.
# model = tfdf.keras.GradientBoostedTreesModel(num_trees=1500)
# model.fit(train_ds)
# Out:
# Use /tmp/tmpmat94dpx as temporary training directory
# Reading training dataset...
# Training dataset read in 0:00:02.707653. Found 849 examples.
# Training model...
# Model trained in 0:00:00.054384
# Compiling model...
# [INFO 26-08-15 05:17:15.0268 UTC kernel.cc:1233] Loading model from path /tmp/tmpmat94dpx/model/ with prefix ef2fef209a0d4f46
# [INFO 26-08-15 05:17:15.0328 UTC decision_forest.cc:734] Model loaded with 300 root(s), 4856 node(s), and 24 input feature(s).
# [INFO 26-08-15 05:17:15.0328 UTC abstract_model.cc:1362] Engine "RandomForestOptPred" built
# [INFO 26-08-15 05:17:15.0328 UTC kernel.cc:1061] Use fast generic engine
# Model compiled.
# CPU times: user 5.64 s, sys: 91.5 ms, total: 5.74 s
# Wall time: 5.99 s

# %%
# Evaluate the model
evaluate = model.evaluate(val_ds, return_dict=True)
print()

for name, value in evaluate.items():
    print(f"{name}: {value:.4f}")
# Out:
# WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 1/1 [==============================] - ETA: 0s - loss: 0.0000e+00 - accuracy: 0.9917
# 1/1 [==============================] - 3s 3s/step - loss: 0.0000e+00 - accuracy: 0.9917
# loss: 0.0000
# accuracy: 0.9917

# %%
# Model Summary
model.summary()
# Out:
# Model: "random_forest_model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
# =================================================================
# Total params: 1 (1.00 Byte)
# Trainable params: 0 (0.00 Byte)
# Non-trainable params: 1 (1.00 Byte)
# _________________________________________________________________
# Type: "RANDOM_FOREST"
# Task: CLASSIFICATION
# Label: "__LABEL"
#
# Input Features (24):
# 	Autocorrelation
# 	ClusterProminence
# 	ClusterShade
# 	ClusterTendency
# 	Contrast
# 	Correlation
# 	DifferenceAverage
# 	DifferenceEntropy
# 	DifferenceVariance
# 	Id
# 	Idm
# 	Idmn
# 	Idn
# 	Imc1
# 	Imc2
# 	InverseVariance
# 	JointAverage
# 	JointEnergy
# 	JointEntropy
# 	MCC
# 	MaximumProbability
# 	SumAverage
# 	SumEntropy
# 	SumSquares
#
# Trained with weights
#
# Variable Importance: INV_MEAN_MIN_DEPTH:
#     1.    "Autocorrelation"  0.321911 ################
#     2.       "JointAverage"  0.294157 ###########
#     3.         "SumAverage"  0.290567 ##########
#     4.         "SumEntropy"  0.270525 #######
#     5.               "Imc1"  0.250351 ####
#     6.        "Correlation"  0.248198 ###
#     7.       "JointEntropy"  0.247908 ###
#     8.        "JointEnergy"  0.247549 ###
#     9.               "Imc2"  0.244329 ###
#    10.                "MCC"  0.242474 ##
#    11. "MaximumProbability"  0.235695 #
#    12.                "Idm"  0.234746 #
#    13.       "ClusterShade"  0.234184 #
#    14. "DifferenceVariance"  0.233201 #
#    15.                 "Id"  0.231069
#    16.    "ClusterTendency"  0.230505
#    17.  "ClusterProminence"  0.230377
#    18.         "SumSquares"  0.228961
#    19.  "DifferenceEntropy"  0.228399
#    20.               "Idmn"  0.228091
#    21.           "Contrast"  0.228060
#    22.    "InverseVariance"  0.227518
#    23.  "DifferenceAverage"  0.226840
#    24.                "Idn"  0.226383
#
# Variable Importance: NUM_AS_ROOT:
#     1.    "Autocorrelation" 76.000000 ################
#     2.       "JointAverage" 56.000000 ###########
#     3.         "SumAverage" 51.000000 ##########
#     4.         "SumEntropy" 38.000000 #######
#     5.       "JointEntropy" 20.000000 ####
#     6.        "JointEnergy" 15.000000 ##
#     7.               "Imc2"  9.000000 #
#     8.                "Idm"  8.000000 #
#     9.               "Imc1"  8.000000 #
#    10.        "Correlation"  6.000000 #
#    11.                "MCC"  4.000000
#    12.                 "Id"  3.000000
#    13. "MaximumProbability"  3.000000
#    14.  "ClusterProminence"  1.000000
#    15.    "ClusterTendency"  1.000000
#    16.         "SumSquares"  1.000000
#
# Variable Importance: NUM_NODES:
#     1.    "Autocorrelation" 306.000000 ################
#     2.       "JointAverage" 280.000000 ##############
#     3.         "SumAverage" 258.000000 #############
#     4.         "SumEntropy" 170.000000 ########
#     5.        "Correlation" 124.000000 #####
#     6.               "Imc1" 122.000000 #####
#     7.                "MCC" 111.000000 #####
#     8.               "Imc2" 108.000000 ####
#     9.        "JointEnergy" 108.000000 ####
#    10.       "JointEntropy" 92.000000 ####
#    11.       "ClusterShade" 84.000000 ###
#    12. "DifferenceVariance" 62.000000 ##
#    13. "MaximumProbability" 61.000000 ##
#    14.                "Idm" 55.000000 #
#    15.    "ClusterTendency" 49.000000 #
#    16.                 "Id" 46.000000 #
#    17.  "ClusterProminence" 37.000000
#    18.  "DifferenceEntropy" 37.000000
#    19.           "Contrast" 33.000000
#    20.         "SumSquares" 33.000000
#    21.               "Idmn" 30.000000
#    22.    "InverseVariance" 30.000000
#    23.                "Idn" 22.000000
#    24.  "DifferenceAverage" 20.000000
#
# Variable Importance: SUM_SCORE:
#     1.    "Autocorrelation" 48593.339251 ################
#     2.       "JointAverage" 39069.585293 ############
#     3.         "SumAverage" 33471.297254 ##########
#     4.         "SumEntropy" 12098.981778 ###
#     5.        "JointEnergy" 6156.736856 #
#     6.       "JointEntropy" 5779.252274 #
#     7.               "Imc2" 4238.146194 #
#     8.        "Correlation" 3674.415810 #
#     9.               "Imc1" 3425.478934 #
#    10.                "MCC" 3095.906234
#    11.                "Idm" 2284.057029
#    12. "MaximumProbability" 1949.500085
#    13.                 "Id" 1502.781181
#    14.       "ClusterShade" 1159.766796
#    15.    "ClusterTendency" 832.824869
#    16. "DifferenceVariance" 782.206137
#    17.  "ClusterProminence" 759.725490
#    18.    "InverseVariance" 569.183835
#    19.         "SumSquares" 512.008876
#    20.  "DifferenceEntropy" 398.736060
#    21.               "Idmn" 349.399117
#    22.           "Contrast" 296.112604
#    23.  "DifferenceAverage" 270.449837
#    24.                "Idn" 240.602180
#
#
#
# Winner takes all: true
# Out-of-bag evaluation: accuracy:0.967929 logloss:0.12163
# Number of trees: 300
# Total number of nodes: 4856
#
# Number of nodes by tree:
# Count: 300 Average: 16.1867 StdDev: 4.27456
# Min: 7 Max: 37 Ignored: 0
# ----------------------------------------------
# [  7,  8)  2   0.67%   0.67%
# [  8, 10)  8   2.67%   3.33% #
# [ 10, 11)  0   0.00%   3.33%
# [ 11, 13) 24   8.00%  11.33% ####
# [ 13, 14) 65  21.67%  33.00% ##########
# [ 14, 16) 66  22.00%  55.00% ##########
# [ 16, 17)  0   0.00%  55.00%
# [ 17, 19) 54  18.00%  73.00% ########
# [ 19, 20) 37  12.33%  85.33% ######
# [ 20, 22) 17   5.67%  91.00% ###
# [ 22, 24) 13   4.33%  95.33% ##
# [ 24, 25)  0   0.00%  95.33%
# [ 25, 27)  4   1.33%  96.67% #
# [ 27, 28)  5   1.67%  98.33% #
# [ 28, 30)  3   1.00%  99.33%
# [ 30, 31)  0   0.00%  99.33%
# [ 31, 33)  0   0.00%  99.33%
# [ 33, 34)  0   0.00%  99.33%
# [ 34, 36)  1   0.33%  99.67%
# [ 36, 37]  1   0.33% 100.00%
#
# Depth by leafs:
# Count: 2578 Average: 3.55974 StdDev: 1.25328
# Min: 1 Max: 9 Ignored: 0
# ----------------------------------------------
# [ 1, 2)  36   1.40%   1.40%
# [ 2, 3) 479  18.58%  19.98% ######
# [ 3, 4) 857  33.24%  53.22% ##########
# [ 4, 5) 658  25.52%  78.74% ########
# [ 5, 6) 377  14.62%  93.37% ####
# [ 6, 7) 123   4.77%  98.14% #
# [ 7, 8)  29   1.12%  99.26%
# [ 8, 9)  17   0.66%  99.92%
# [ 9, 9]   2   0.08% 100.00%
#
# Number of training obs by leaf:
# Count: 2578 Average: 98.7975 StdDev: 212.724
# Min: 5 Max: 793 Ignored: 0
# ----------------------------------------------
# [   5,  44) 2003  77.70%  77.70% ##########
# [  44,  83)  143   5.55%  83.24% #
# [  83, 123)   52   2.02%  85.26%
# [ 123, 162)   21   0.81%  86.07%
# [ 162, 202)   11   0.43%  86.50%
# [ 202, 241)    7   0.27%  86.77%
# [ 241, 281)   18   0.70%  87.47%
# [ 281, 320)   22   0.85%  88.32%
# [ 320, 360)   10   0.39%  88.71%
# [ 360, 399)   12   0.47%  89.18%
# [ 399, 438)   13   0.50%  89.68%
# [ 438, 478)   15   0.58%  90.26%
# [ 478, 517)   11   0.43%  90.69%
# [ 517, 557)    4   0.16%  90.85%
# [ 557, 596)    1   0.04%  90.88%
# [ 596, 636)    7   0.27%  91.16%
# [ 636, 675)   20   0.78%  91.93%
# [ 675, 715)   68   2.64%  94.57%
# [ 715, 754)   72   2.79%  97.36%
# [ 754, 793]   68   2.64% 100.00%
#
# Attribute in nodes:
# 	306 : Autocorrelation [NUMERICAL]
# 	280 : JointAverage [NUMERICAL]
# 	258 : SumAverage [NUMERICAL]
# 	170 : SumEntropy [NUMERICAL]
# 	124 : Correlation [NUMERICAL]
# 	122 : Imc1 [NUMERICAL]
# 	111 : MCC [NUMERICAL]
# 	108 : JointEnergy [NUMERICAL]
# 	108 : Imc2 [NUMERICAL]
# 	92 : JointEntropy [NUMERICAL]
# 	84 : ClusterShade [NUMERICAL]
# 	62 : DifferenceVariance [NUMERICAL]
# 	61 : MaximumProbability [NUMERICAL]
# 	55 : Idm [NUMERICAL]
# 	49 : ClusterTendency [NUMERICAL]
# 	46 : Id [NUMERICAL]
# 	37 : DifferenceEntropy [NUMERICAL]
# 	37 : ClusterProminence [NUMERICAL]
# 	33 : SumSquares [NUMERICAL]
# 	33 : Contrast [NUMERICAL]
# 	30 : InverseVariance [NUMERICAL]
# 	30 : Idmn [NUMERICAL]
# 	22 : Idn [NUMERICAL]
# 	20 : DifferenceAverage [NUMERICAL]
#
# Attribute in nodes with depth <= 0:
# 	76 : Autocorrelation [NUMERICAL]
# 	56 : JointAverage [NUMERICAL]
# 	51 : SumAverage [NUMERICAL]
# 	38 : SumEntropy [NUMERICAL]
# 	20 : JointEntropy [NUMERICAL]
# 	15 : JointEnergy [NUMERICAL]
# 	9 : Imc2 [NUMERICAL]
# 	8 : Imc1 [NUMERICAL]
# 	8 : Idm [NUMERICAL]
# 	6 : Correlation [NUMERICAL]
# 	4 : MCC [NUMERICAL]
# 	3 : MaximumProbability [NUMERICAL]
# 	3 : Id [NUMERICAL]
# 	1 : SumSquares [NUMERICAL]
# 	1 : ClusterTendency [NUMERICAL]
# 	1 : ClusterProminence [NUMERICAL]
#
# Attribute in nodes with depth <= 1:
# 	168 : Autocorrelation [NUMERICAL]
# 	134 : JointAverage [NUMERICAL]
# 	117 : SumAverage [NUMERICAL]
# 	83 : SumEntropy [NUMERICAL]
# 	55 : JointEnergy [NUMERICAL]
# 	52 : JointEntropy [NUMERICAL]
# 	47 : Imc1 [NUMERICAL]
# 	41 : Correlation [NUMERICAL]
# 	37 : Imc2 [NUMERICAL]
# 	29 : MCC [NUMERICAL]
# 	21 : MaximumProbability [NUMERICAL]
# 	20 : Idm [NUMERICAL]
# 	13 : Id [NUMERICAL]
# 	11 : DifferenceVariance [NUMERICAL]
# 	10 : ClusterShade [NUMERICAL]
# 	8 : ClusterProminence [NUMERICAL]
# 	5 : ClusterTendency [NUMERICAL]
# 	3 : SumSquares [NUMERICAL]
# 	3 : Contrast [NUMERICAL]
# 	2 : Idmn [NUMERICAL]
# 	2 : DifferenceEntropy [NUMERICAL]
# 	1 : InverseVariance [NUMERICAL]
# 	1 : Idn [NUMERICAL]
# 	1 : DifferenceAverage [NUMERICAL]
#
# Attribute in nodes with depth <= 2:
# 	253 : Autocorrelation [NUMERICAL]
# 	212 : JointAverage [NUMERICAL]
# 	194 : SumAverage [NUMERICAL]
# 	118 : SumEntropy [NUMERICAL]
# 	91 : Correlation [NUMERICAL]
# 	77 : Imc1 [NUMERICAL]
# 	75 : JointEnergy [NUMERICAL]
# 	74 : MCC [NUMERICAL]
# 	65 : Imc2 [NUMERICAL]
# 	64 : JointEntropy [NUMERICAL]
# 	42 : ClusterShade [NUMERICAL]
# 	36 : MaximumProbability [NUMERICAL]
# 	33 : DifferenceVariance [NUMERICAL]
# 	32 : Idm [NUMERICAL]
# 	24 : Id [NUMERICAL]
# 	20 : ClusterTendency [NUMERICAL]
# 	19 : InverseVariance [NUMERICAL]
# 	17 : ClusterProminence [NUMERICAL]
# 	15 : DifferenceEntropy [NUMERICAL]
# 	14 : SumSquares [NUMERICAL]
# 	13 : Contrast [NUMERICAL]
# 	11 : Idmn [NUMERICAL]
# 	7 : Idn [NUMERICAL]
# 	7 : DifferenceAverage [NUMERICAL]
#
# Attribute in nodes with depth <= 3:
# 	282 : Autocorrelation [NUMERICAL]
# 	258 : JointAverage [NUMERICAL]
# 	235 : SumAverage [NUMERICAL]
# 	148 : SumEntropy [NUMERICAL]
# 	113 : Correlation [NUMERICAL]
# 	106 : Imc1 [NUMERICAL]
# 	91 : Imc2 [NUMERICAL]
# 	90 : MCC [NUMERICAL]
# 	89 : JointEnergy [NUMERICAL]
# 	81 : JointEntropy [NUMERICAL]
# 	64 : ClusterShade [NUMERICAL]
# 	52 : MaximumProbability [NUMERICAL]
# 	52 : DifferenceVariance [NUMERICAL]
# 	43 : Idm [NUMERICAL]
# 	40 : Id [NUMERICAL]
# 	34 : ClusterTendency [NUMERICAL]
# 	30 : DifferenceEntropy [NUMERICAL]
# 	29 : ClusterProminence [NUMERICAL]
# 	24 : SumSquares [NUMERICAL]
# 	24 : InverseVariance [NUMERICAL]
# 	21 : Idmn [NUMERICAL]
# 	21 : Contrast [NUMERICAL]
# 	14 : DifferenceAverage [NUMERICAL]
# 	13 : Idn [NUMERICAL]
#
# Attribute in nodes with depth <= 5:
# 	304 : Autocorrelation [NUMERICAL]
# 	279 : JointAverage [NUMERICAL]
# 	258 : SumAverage [NUMERICAL]
# 	169 : SumEntropy [NUMERICAL]
# 	123 : Correlation [NUMERICAL]
# 	120 : Imc1 [NUMERICAL]
# 	110 : MCC [NUMERICAL]
# 	108 : Imc2 [NUMERICAL]
# 	103 : JointEnergy [NUMERICAL]
# 	90 : JointEntropy [NUMERICAL]
# 	82 : ClusterShade [NUMERICAL]
# 	61 : DifferenceVariance [NUMERICAL]
# 	60 : MaximumProbability [NUMERICAL]
# 	53 : Idm [NUMERICAL]
# 	48 : ClusterTendency [NUMERICAL]
# 	46 : Id [NUMERICAL]
# 	36 : DifferenceEntropy [NUMERICAL]
# 	36 : ClusterProminence [NUMERICAL]
# 	31 : SumSquares [NUMERICAL]
# 	31 : Contrast [NUMERICAL]
# 	30 : Idmn [NUMERICAL]
# 	29 : InverseVariance [NUMERICAL]
# 	22 : Idn [NUMERICAL]
# 	20 : DifferenceAverage [NUMERICAL]
#
# Condition type in nodes:
# 	2278 : HigherCondition
# Condition type in nodes with depth <= 0:
# 	300 : HigherCondition
# Condition type in nodes with depth <= 1:
# 	864 : HigherCondition
# Condition type in nodes with depth <= 2:
# 	1513 : HigherCondition
# Condition type in nodes with depth <= 3:
# 	1954 : HigherCondition
# Condition type in nodes with depth <= 5:
# 	2249 : HigherCondition
# Node format: NOT_SET
#
# Training OOB:
# 	trees: 1, Out-of-bag evaluation: accuracy:0.934038 logloss:2.37752
# 	trees: 13, Out-of-bag evaluation: accuracy:0.937507 logloss:1.16057
# 	trees: 23, Out-of-bag evaluation: accuracy:0.958495 logloss:0.454233
# 	trees: 33, Out-of-bag evaluation: accuracy:0.959752 logloss:0.463149
# 	trees: 43, Out-of-bag evaluation: accuracy:0.959123 logloss:0.14629
# 	trees: 53, Out-of-bag evaluation: accuracy:0.959123 logloss:0.136247
# 	trees: 63, Out-of-bag evaluation: accuracy:0.959123 logloss:0.14084
# 	trees: 73, Out-of-bag evaluation: accuracy:0.968557 logloss:0.133395
# 	trees: 84, Out-of-bag evaluation: accuracy:0.967929 logloss:0.137197
# 	trees: 94, Out-of-bag evaluation: accuracy:0.968557 logloss:0.135538
# 	trees: 104, Out-of-bag evaluation: accuracy:0.969186 logloss:0.138641
# 	trees: 114, Out-of-bag evaluation: accuracy:0.968557 logloss:0.137062
# 	trees: 124, Out-of-bag evaluation: accuracy:0.967301 logloss:0.139711
# 	trees: 134, Out-of-bag evaluation: accuracy:0.967301 logloss:0.119063
# 	trees: 144, Out-of-bag evaluation: accuracy:0.967929 logloss:0.118334
# 	trees: 154, Out-of-bag evaluation: accuracy:0.967929 logloss:0.118065
# 	trees: 164, Out-of-bag evaluation: accuracy:0.967929 logloss:0.118561
# 	trees: 175, Out-of-bag evaluation: accuracy:0.967929 logloss:0.119208
# 	trees: 185, Out-of-bag evaluation: accuracy:0.967929 logloss:0.116541
# 	trees: 195, Out-of-bag evaluation: accuracy:0.967929 logloss:0.116607
# 	trees: 205, Out-of-bag evaluation: accuracy:0.967929 logloss:0.118098
# 	trees: 215, Out-of-bag evaluation: accuracy:0.967929 logloss:0.118095
# 	trees: 225, Out-of-bag evaluation: accuracy:0.967929 logloss:0.120149
# 	trees: 236, Out-of-bag evaluation: accuracy:0.967929 logloss:0.12002
# 	trees: 247, Out-of-bag evaluation: accuracy:0.967929 logloss:0.120517
# 	trees: 257, Out-of-bag evaluation: accuracy:0.967929 logloss:0.121805
# 	trees: 267, Out-of-bag evaluation: accuracy:0.967929 logloss:0.122566
# 	trees: 277, Out-of-bag evaluation: accuracy:0.967929 logloss:0.1227
# 	trees: 287, Out-of-bag evaluation: accuracy:0.967929 logloss:0.123175
# 	trees: 297, Out-of-bag evaluation: accuracy:0.967929 logloss:0.123501
# 	trees: 300, Out-of-bag evaluation: accuracy:0.967929 logloss:0.12163

# %%
# Model features
model.make_inspector().features()
# Out:
# ["Autocorrelation" (1; #0),
#  "ClusterProminence" (1; #1),
#  "ClusterShade" (1; #2),
#  "ClusterTendency" (1; #3),
#  "Contrast" (1; #4),
#  "Correlation" (1; #5),
#  "DifferenceAverage" (1; #6),
#  "DifferenceEntropy" (1; #7),
#  "DifferenceVariance" (1; #8),
#  "Id" (1; #9),
#  "Idm" (1; #10),
#  "Idmn" (1; #11),
#  "Idn" (1; #12),
#  "Imc1" (1; #13),
#  "Imc2" (1; #14),
#  "InverseVariance" (1; #15),
#  "JointAverage" (1; #16),
#  "JointEnergy" (1; #17),
#  "JointEntropy" (1; #18),
#  "MCC" (1; #19),
#  "MaximumProbability" (1; #20),
#  "SumAverage" (1; #21),
#  "SumEntropy" (1; #22),
#  "SumSquares" (1; #23)]

# %%
# Feature importance
model.make_inspector().variable_importances()
# Out:
# {'INV_MEAN_MIN_DEPTH': [("Autocorrelation" (1; #0), 0.3219105462793363),
#   ("JointAverage" (1; #16), 0.2941571389168342),
#   ("SumAverage" (1; #21), 0.29056749617575833),
#   ("SumEntropy" (1; #22), 0.27052541521815143),
#   ("Imc1" (1; #13), 0.2503508758170265),
#   ("Correlation" (1; #5), 0.24819788072073262),
#   ("JointEntropy" (1; #18), 0.2479084852382516),
#   ("JointEnergy" (1; #17), 0.2475492794637305),
#   ("Imc2" (1; #14), 0.2443292430089356),
#   ("MCC" (1; #19), 0.24247444629189124),
#   ("MaximumProbability" (1; #20), 0.2356953518596533),
#   ("Idm" (1; #10), 0.23474608255252052),
#   ("ClusterShade" (1; #2), 0.23418411457444457),
#   ("DifferenceVariance" (1; #8), 0.2332011801963902),
#   ("Id" (1; #9), 0.2310692861202462),
#   ("ClusterTendency" (1; #3), 0.2305053104327975),
#   ("ClusterProminence" (1; #1), 0.23037726783430001),
#   ("SumSquares" (1; #23), 0.22896070302240035),
#   ("DifferenceEntropy" (1; #7), 0.22839875027126208),
#   ("Idmn" (1; #11), 0.22809069188713846),
#   ("Contrast" (1; #4), 0.22806000656466466),
#   ("InverseVariance" (1; #15), 0.22751818061474371),
#   ("DifferenceAverage" (1; #6), 0.22683980712172747),
#   ("Idn" (1; #12), 0.2263827536966993)],
#  'NUM_AS_ROOT': [("Autocorrelation" (1; #0), 76.0),
#   ("JointAverage" (1; #16), 56.0),
#   ("SumAverage" (1; #21), 51.0),
#   ("SumEntropy" (1; #22), 38.0),
#   ("JointEntropy" (1; #18), 20.0),
#   ("JointEnergy" (1; #17), 15.0),
#   ("Imc2" (1; #14), 9.0),
#   ("Idm" (1; #10), 8.0),
#   ("Imc1" (1; #13), 8.0),
#   ("Correlation" (1; #5), 6.0),
#   ("MCC" (1; #19), 4.0),
#   ("Id" (1; #9), 3.0),
#   ("MaximumProbability" (1; #20), 3.0),
#   ("ClusterProminence" (1; #1), 1.0),
#   ("ClusterTendency" (1; #3), 1.0),
#   ("SumSquares" (1; #23), 1.0)],
#  'SUM_SCORE': [("Autocorrelation" (1; #0), 48593.33925062464),
#   ("JointAverage" (1; #16), 39069.585293383076),
#   ("SumAverage" (1; #21), 33471.297253932105),
#   ("SumEntropy" (1; #22), 12098.981777605799),
#   ("JointEnergy" (1; #17), 6156.736856331379),
#   ("JointEntropy" (1; #18), 5779.252274162458),
#   ("Imc2" (1; #14), 4238.146193756223),
#   ("Correlation" (1; #5), 3674.4158104622607),
#   ("Imc1" (1; #13), 3425.47893424956),
#   ("MCC" (1; #19), 3095.9062342153866),
#   ("Idm" (1; #10), 2284.057028523827),
#   ("MaximumProbability" (1; #20), 1949.5000854955194),
#   ("Id" (1; #9), 1502.781180943148),
#   ("ClusterShade" (1; #2), 1159.7667956278108),
#   ("ClusterTendency" (1; #3), 832.8248693866693),
#   ("DifferenceVariance" (1; #8), 782.2061373295153),
#   ("ClusterProminence" (1; #1), 759.7254903201368),
#   ("InverseVariance" (1; #15), 569.1838348020187),
#   ("SumSquares" (1; #23), 512.008876084196),
#   ("DifferenceEntropy" (1; #7), 398.7360599766716),
#   ("Idmn" (1; #11), 349.39911700374995),
#   ("Contrast" (1; #4), 296.11260412083266),
#   ("DifferenceAverage" (1; #6), 270.4498374035191),
#   ("Idn" (1; #12), 240.6021795432131)],
#  'NUM_NODES': [("Autocorrelation" (1; #0), 306.0),
#   ("JointAverage" (1; #16), 280.0),
#   ("SumAverage" (1; #21), 258.0),
#   ("SumEntropy" (1; #22), 170.0),
#   ("Correlation" (1; #5), 124.0),
#   ("Imc1" (1; #13), 122.0),
#   ("MCC" (1; #19), 111.0),
#   ("Imc2" (1; #14), 108.0),
#   ("JointEnergy" (1; #17), 108.0),
#   ("JointEntropy" (1; #18), 92.0),
#   ("ClusterShade" (1; #2), 84.0),
#   ("DifferenceVariance" (1; #8), 62.0),
#   ("MaximumProbability" (1; #20), 61.0),
#   ("Idm" (1; #10), 55.0),
#   ("ClusterTendency" (1; #3), 49.0),
#   ("Id" (1; #9), 46.0),
#   ("ClusterProminence" (1; #1), 37.0),
#   ("DifferenceEntropy" (1; #7), 37.0),
#   ("Contrast" (1; #4), 33.0),
#   ("SumSquares" (1; #23), 33.0),
#   ("Idmn" (1; #11), 30.0),
#   ("InverseVariance" (1; #15), 30.0),
#   ("Idn" (1; #12), 22.0),
#   ("DifferenceAverage" (1; #6), 20.0)]}

# %%
# Model self evaluation
model.make_inspector().evaluation()
# Out:
# Evaluation(num_examples=849, accuracy=0.9679292693584713, loss=0.12162987413056699, rmse=None, ndcg=None, aucs=None, auuc=None, qini=None)

# %%
logs = model.make_inspector().training_logs()

plt.figure(figsize=(12, 4))
plt.subplot(1, 2, 1)
plt.plot([log.num_trees for log in logs], [log.evaluation.accuracy for log in logs])
plt.xlabel("Number of trees")
plt.ylabel("Accuracy (out-of-bag)")
plt.subplot(1, 2, 2)
plt.plot([log.num_trees for log in logs], [log.evaluation.loss for log in logs])
plt.xlabel("Number of trees")
plt.ylabel("Logloss (out-of-bag)")
plt.show()

# %% [markdown]
# Calculate the score of our hold-out validation dataset

# %%
predictions = model.predict(val_ds)
y_true      = validation_data["label"]

from sklearn.metrics import roc_auc_score
ROC_AUC = roc_auc_score(y_true, predictions)
print("The ROC AUC score is %.5f" % ROC_AUC )
# Out:
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 66ms/step
# The ROC AUC score is 0.99115

# %%
# Compute binary classification metrics with sklearn
import numpy as np
from sklearn.metrics import (
    accuracy_score,
    precision_score,
    recall_score,
    f1_score,
    roc_auc_score,
    average_precision_score,
    confusion_matrix,
    classification_report,
    matthews_corrcoef,
    log_loss,
    brier_score_loss,
)

# Get predictions (probabilities or class labels)
preds = model.predict(test_ds)
# If model outputs probabilities, convert to labels by threshold 0.5
if preds.ndim == 2:
    # For TFDF classification, preds may be class probabilities with shape (N, 2)
    if preds.shape[1] == 2:
        pos_probs = preds[:, 1]
    else:
        # If single-probability column (positive class)
        pos_probs = preds[:, -1]
    y_pred = (pos_probs >= 0.5).astype(int)
else:
    # Already class labels
    y_pred = preds.astype(int)
    pos_probs = None

# Ground truth labels (must be 0/1 integers)
y_true = test_data["label"].astype(int).to_numpy()

# Core metrics
metrics = {}
metrics["accuracy"] = accuracy_score(y_true, y_pred)
metrics["precision"] = precision_score(y_true, y_pred, zero_division=0)
metrics["recall"] = recall_score(y_true, y_pred, zero_division=0)
metrics["f1"] = f1_score(y_true, y_pred, zero_division=0)
metrics["mcc"] = matthews_corrcoef(y_true, y_pred)

# Probabilistic metrics (only if we have probabilities)
if pos_probs is not None:
    metrics["roc_auc"] = roc_auc_score(y_true, pos_probs)
    metrics["pr_auc"] = average_precision_score(y_true, pos_probs)
    metrics["log_loss"] = log_loss(y_true, pos_probs, labels=[0,1])
    metrics["brier_score"] = brier_score_loss(y_true, pos_probs)

# Confusion matrix and detailed report
cm = confusion_matrix(y_true, y_pred, labels=[0,1])
report = classification_report(y_true, y_pred, digits=4)

print("Sklearn binary metrics:")
for k, v in metrics.items():
    print(f"{k}: {v:.4f}")
print("\nConfusion matrix:\n", cm)
print("\nClassification report:\n", report)
# Out:
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 74ms/step
# Sklearn binary metrics:
# accuracy: 0.9836
# precision: 0.8182
# recall: 0.8182
# f1: 0.8182
# mcc: 0.8096
# roc_auc: 0.9934
# pr_auc: 0.8213
# log_loss: 0.0491
# brier_score: 0.0138
#
# Confusion matrix:
#  [[231   2]
#  [  2   9]]
#
# Classification report:
#                precision    recall  f1-score   support
#
#            0     0.9914    0.9914    0.9914       233
#            1     0.8182    0.8182    0.8182        11
#
#     accuracy                         0.9836       244
#    macro avg     0.9048    0.9048    0.9048       244
# weighted avg     0.9836    0.9836    0.9836       244
