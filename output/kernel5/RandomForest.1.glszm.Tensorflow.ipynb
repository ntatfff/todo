# %%
# Import packages and modules
import numpy  as np
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow_decision_forests as tfdf

from sklearn.model_selection import train_test_split
# Out:
# 2026-08-15 05:18:42.129374: I tensorflow/core/util/port.cc:113] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2026-08-15 05:18:42.493686: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2026-08-15 05:18:47.312238: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
# Check the version of TensorFlow Decision Forests
print("Found TensorFlow Decision Forests v" + tfdf.__version__)
# Out:
# Found TensorFlow Decision Forests v1.9.1

# %%
datasetPath = 'dataset/firstorder/kernel5/dataset.csv'

# %%
# Parameters
datasetPath = "dataset/glszm/kernel5/1.dataset.csv"

# %%
# train/validation/test = 70/10/20
dataset = pd.read_csv(datasetPath)

train_data, temp_data = train_test_split(dataset, test_size=0.3, random_state=42)
validation_data, test_data = train_test_split(temp_data, test_size=2/3, random_state=42)

# %%
from sklearn.utils.class_weight import compute_class_weight

# tinh class weight tren tap train
classes = np.array([0, 1])
weights = compute_class_weight(class_weight="balanced", classes=classes, y=train_data["label"])
class_weight = {0: weights[0], 1: weights[1]}

# gan sample_weight cho tung dong
train_data["sample_weight"] = train_data["label"].map(class_weight)
validation_data["sample_weight"] = validation_data["label"].map(class_weight)
test_data["sample_weight"] = test_data["label"].map(class_weight)

# Convert the dataset into a TensorFlow dataset.
train_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    train_data, label="label", weight="sample_weight"
)         
val_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    validation_data, label="label", weight="sample_weight"
)
test_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    test_data, label="label", weight="sample_weight"
)
# Out:
# 2026-08-15 05:19:00.296615: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:984] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2026-08-15 05:19:00.298497: W tensorflow/core/common_runtime/gpu/gpu_device.cc:2251] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...

# %%
import keras

# %%
# %%time

# Train a Random Forest model.
model = tfdf.keras.RandomForestModel()

# Add evaluation metrics
model.compile(
    metrics=["accuracy"]
)
model.fit(x=train_ds)

# # Train a Gradient Boosted Trees model.
# model = tfdf.keras.GradientBoostedTreesModel(num_trees=1500)
# model.fit(train_ds)
# Out:
# Use /tmp/tmpr4uh__5c as temporary training directory
# Reading training dataset...
# Training dataset read in 0:00:02.610107. Found 849 examples.
# Training model...
# Model trained in 0:00:00.053905
# Compiling model...
# [INFO 26-08-15 05:19:03.1275 UTC kernel.cc:1233] Loading model from path /tmp/tmpr4uh__5c/model/ with prefix 7a97359faef74209
# [INFO 26-08-15 05:19:03.1343 UTC decision_forest.cc:734] Model loaded with 300 root(s), 5126 node(s), and 16 input feature(s).
# [INFO 26-08-15 05:19:03.1343 UTC abstract_model.cc:1362] Engine "RandomForestOptPred" built
# [INFO 26-08-15 05:19:03.1344 UTC kernel.cc:1061] Use fast generic engine
# Model compiled.
# CPU times: user 5.61 s, sys: 39.6 ms, total: 5.65 s
# Wall time: 5.89 s

# %%
# Evaluate the model
evaluate = model.evaluate(val_ds, return_dict=True)
print()

for name, value in evaluate.items():
    print(f"{name}: {value:.4f}")
# Out:
# WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 1/1 [==============================] - ETA: 0s - loss: 0.0000e+00 - accuracy: 0.9917
# 1/1 [==============================] - 4s 4s/step - loss: 0.0000e+00 - accuracy: 0.9917
# loss: 0.0000
# accuracy: 0.9917

# %%
# Model Summary
model.summary()
# Out:
# Model: "random_forest_model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
# =================================================================
# Total params: 1 (1.00 Byte)
# Trainable params: 0 (0.00 Byte)
# Non-trainable params: 1 (1.00 Byte)
# _________________________________________________________________
# Type: "RANDOM_FOREST"
# Task: CLASSIFICATION
# Label: "__LABEL"
#
# Input Features (16):
# 	GrayLevelNonUniformity
# 	GrayLevelNonUniformityNormalized
# 	GrayLevelVariance
# 	HighGrayLevelZoneEmphasis
# 	LargeAreaEmphasis
# 	LargeAreaHighGrayLevelEmphasis
# 	LargeAreaLowGrayLevelEmphasis
# 	LowGrayLevelZoneEmphasis
# 	SizeZoneNonUniformity
# 	SizeZoneNonUniformityNormalized
# 	SmallAreaEmphasis
# 	SmallAreaHighGrayLevelEmphasis
# 	SmallAreaLowGrayLevelEmphasis
# 	ZoneEntropy
# 	ZonePercentage
# 	ZoneVariance
#
# Trained with weights
#
# Variable Importance: INV_MEAN_MIN_DEPTH:
#     1.   "SmallAreaHighGrayLevelEmphasis"  0.329397 ################
#     2.        "HighGrayLevelZoneEmphasis"  0.321440 ##############
#     3.         "LowGrayLevelZoneEmphasis"  0.281046 #########
#     4.    "SmallAreaLowGrayLevelEmphasis"  0.261264 ######
#     5.    "LargeAreaLowGrayLevelEmphasis"  0.254633 #####
#     6.                      "ZoneEntropy"  0.235618 ##
#     7.                "GrayLevelVariance"  0.234199 ##
#     8.           "GrayLevelNonUniformity"  0.231820 #
#     9. "GrayLevelNonUniformityNormalized"  0.229190 #
#    10.                   "ZonePercentage"  0.226537 #
#    11.                "LargeAreaEmphasis"  0.223207
#    12.                     "ZoneVariance"  0.221016
#    13.   "LargeAreaHighGrayLevelEmphasis"  0.220887
#    14.  "SizeZoneNonUniformityNormalized"  0.219508
#    15.                "SmallAreaEmphasis"  0.218792
#    16.            "SizeZoneNonUniformity"  0.218748
#
# Variable Importance: NUM_AS_ROOT:
#     1.   "SmallAreaHighGrayLevelEmphasis" 86.000000 ################
#     2.        "HighGrayLevelZoneEmphasis" 77.000000 ##############
#     3.         "LowGrayLevelZoneEmphasis" 45.000000 ########
#     4.    "SmallAreaLowGrayLevelEmphasis" 31.000000 #####
#     5.    "LargeAreaLowGrayLevelEmphasis" 23.000000 ####
#     6.                      "ZoneEntropy" 12.000000 ##
#     7.                   "ZonePercentage"  9.000000 #
#     8.                "GrayLevelVariance"  8.000000 #
#     9. "GrayLevelNonUniformityNormalized"  4.000000
#    10.                "LargeAreaEmphasis"  2.000000
#    11.            "SizeZoneNonUniformity"  2.000000
#    12.  "SizeZoneNonUniformityNormalized"  1.000000
#
# Variable Importance: NUM_NODES:
#     1.        "HighGrayLevelZoneEmphasis" 323.000000 ################
#     2.   "SmallAreaHighGrayLevelEmphasis" 309.000000 ###############
#     3.         "LowGrayLevelZoneEmphasis" 250.000000 ###########
#     4.    "SmallAreaLowGrayLevelEmphasis" 194.000000 ########
#     5.    "LargeAreaLowGrayLevelEmphasis" 185.000000 #######
#     6.                      "ZoneEntropy" 166.000000 ######
#     7. "GrayLevelNonUniformityNormalized" 150.000000 #####
#     8.                "GrayLevelVariance" 145.000000 #####
#     9.           "GrayLevelNonUniformity" 113.000000 ###
#    10.                "LargeAreaEmphasis" 103.000000 ##
#    11.                     "ZoneVariance" 98.000000 ##
#    12.                   "ZonePercentage" 92.000000 #
#    13.  "SizeZoneNonUniformityNormalized" 82.000000 #
#    14.                "SmallAreaEmphasis" 72.000000
#    15.   "LargeAreaHighGrayLevelEmphasis" 69.000000
#    16.            "SizeZoneNonUniformity" 62.000000
#
# Variable Importance: SUM_SCORE:
#     1.   "SmallAreaHighGrayLevelEmphasis" 53410.334586 ################
#     2.        "HighGrayLevelZoneEmphasis" 45195.132787 #############
#     3.         "LowGrayLevelZoneEmphasis" 21758.313850 ######
#     4.    "SmallAreaLowGrayLevelEmphasis" 14156.666037 ####
#     5.    "LargeAreaLowGrayLevelEmphasis" 8861.100379 ##
#     6.                      "ZoneEntropy" 7756.294855 ##
#     7. "GrayLevelNonUniformityNormalized" 4764.971303 #
#     8.                "GrayLevelVariance" 4008.982138 #
#     9.                   "ZonePercentage" 2355.195080
#    10.           "GrayLevelNonUniformity" 1953.723631
#    11.                "LargeAreaEmphasis" 1799.610861
#    12.                     "ZoneVariance" 1414.418079
#    13.   "LargeAreaHighGrayLevelEmphasis" 825.212303
#    14.            "SizeZoneNonUniformity" 781.664178
#    15.  "SizeZoneNonUniformityNormalized" 638.886296
#    16.                "SmallAreaEmphasis" 369.007486
#
#
#
# Winner takes all: true
# Out-of-bag evaluation: accuracy:0.934284 logloss:0.131901
# Number of trees: 300
# Total number of nodes: 5126
#
# Number of nodes by tree:
# Count: 300 Average: 17.0867 StdDev: 3.25051
# Min: 7 Max: 27 Ignored: 0
# ----------------------------------------------
# [  7,  8)  1   0.33%   0.33%
# [  8,  9)  0   0.00%   0.33%
# [  9, 10)  0   0.00%   0.33%
# [ 10, 11)  0   0.00%   0.33%
# [ 11, 12) 11   3.67%   4.00% #
# [ 12, 13)  0   0.00%   4.00%
# [ 13, 14) 40  13.33%  17.33% #####
# [ 14, 15)  0   0.00%  17.33%
# [ 15, 16) 62  20.67%  38.00% ########
# [ 16, 17)  0   0.00%  38.00%
# [ 17, 18) 76  25.33%  63.33% ##########
# [ 18, 19)  0   0.00%  63.33%
# [ 19, 20) 58  19.33%  82.67% ########
# [ 20, 21)  0   0.00%  82.67%
# [ 21, 22) 31  10.33%  93.00% ####
# [ 22, 23)  0   0.00%  93.00%
# [ 23, 24) 14   4.67%  97.67% ##
# [ 24, 25)  0   0.00%  97.67%
# [ 25, 26)  4   1.33%  99.00% #
# [ 26, 27]  3   1.00% 100.00%
#
# Depth by leafs:
# Count: 2713 Average: 3.76152 StdDev: 1.39489
# Min: 1 Max: 9 Ignored: 0
# ----------------------------------------------
# [ 1, 2)  55   2.03%   2.03% #
# [ 2, 3) 501  18.47%  20.49% #######
# [ 3, 4) 690  25.43%  45.93% ##########
# [ 4, 5) 662  24.40%  70.33% ##########
# [ 5, 6) 493  18.17%  88.50% #######
# [ 6, 7) 236   8.70%  97.20% ###
# [ 7, 8)  61   2.25%  99.45% #
# [ 8, 9)  13   0.48%  99.93%
# [ 9, 9]   2   0.07% 100.00%
#
# Number of training obs by leaf:
# Count: 2713 Average: 93.8813 StdDev: 223.181
# Min: 5 Max: 801 Ignored: 0
# ----------------------------------------------
# [   5,  44) 2289  84.37%  84.37% ##########
# [  44,  84)   70   2.58%  86.95%
# [  84, 124)   11   0.41%  87.36%
# [ 124, 164)   13   0.48%  87.84%
# [ 164, 204)    8   0.29%  88.13%
# [ 204, 244)    6   0.22%  88.35%
# [ 244, 283)    4   0.15%  88.50%
# [ 283, 323)    7   0.26%  88.76%
# [ 323, 363)    0   0.00%  88.76%
# [ 363, 403)   12   0.44%  89.20%
# [ 403, 443)    6   0.22%  89.42%
# [ 443, 483)    3   0.11%  89.53%
# [ 483, 523)    6   0.22%  89.75%
# [ 523, 562)    4   0.15%  89.90%
# [ 562, 602)    6   0.22%  90.12%
# [ 602, 642)   10   0.37%  90.49%
# [ 642, 682)   18   0.66%  91.15%
# [ 682, 722)   43   1.58%  92.74%
# [ 722, 762)   73   2.69%  95.43%
# [ 762, 801]  124   4.57% 100.00% #
#
# Attribute in nodes:
# 	323 : HighGrayLevelZoneEmphasis [NUMERICAL]
# 	309 : SmallAreaHighGrayLevelEmphasis [NUMERICAL]
# 	250 : LowGrayLevelZoneEmphasis [NUMERICAL]
# 	194 : SmallAreaLowGrayLevelEmphasis [NUMERICAL]
# 	185 : LargeAreaLowGrayLevelEmphasis [NUMERICAL]
# 	166 : ZoneEntropy [NUMERICAL]
# 	150 : GrayLevelNonUniformityNormalized [NUMERICAL]
# 	145 : GrayLevelVariance [NUMERICAL]
# 	113 : GrayLevelNonUniformity [NUMERICAL]
# 	103 : LargeAreaEmphasis [NUMERICAL]
# 	98 : ZoneVariance [NUMERICAL]
# 	92 : ZonePercentage [NUMERICAL]
# 	82 : SizeZoneNonUniformityNormalized [NUMERICAL]
# 	72 : SmallAreaEmphasis [NUMERICAL]
# 	69 : LargeAreaHighGrayLevelEmphasis [NUMERICAL]
# 	62 : SizeZoneNonUniformity [NUMERICAL]
#
# Attribute in nodes with depth <= 0:
# 	86 : SmallAreaHighGrayLevelEmphasis [NUMERICAL]
# 	77 : HighGrayLevelZoneEmphasis [NUMERICAL]
# 	45 : LowGrayLevelZoneEmphasis [NUMERICAL]
# 	31 : SmallAreaLowGrayLevelEmphasis [NUMERICAL]
# 	23 : LargeAreaLowGrayLevelEmphasis [NUMERICAL]
# 	12 : ZoneEntropy [NUMERICAL]
# 	9 : ZonePercentage [NUMERICAL]
# 	8 : GrayLevelVariance [NUMERICAL]
# 	4 : GrayLevelNonUniformityNormalized [NUMERICAL]
# 	2 : SizeZoneNonUniformity [NUMERICAL]
# 	2 : LargeAreaEmphasis [NUMERICAL]
# 	1 : SizeZoneNonUniformityNormalized [NUMERICAL]
#
# Attribute in nodes with depth <= 1:
# 	187 : SmallAreaHighGrayLevelEmphasis [NUMERICAL]
# 	164 : HighGrayLevelZoneEmphasis [NUMERICAL]
# 	106 : LowGrayLevelZoneEmphasis [NUMERICAL]
# 	74 : SmallAreaLowGrayLevelEmphasis [NUMERICAL]
# 	69 : ZoneEntropy [NUMERICAL]
# 	54 : LargeAreaLowGrayLevelEmphasis [NUMERICAL]
# 	47 : GrayLevelNonUniformityNormalized [NUMERICAL]
# 	46 : GrayLevelVariance [NUMERICAL]
# 	23 : LargeAreaEmphasis [NUMERICAL]
# 	23 : GrayLevelNonUniformity [NUMERICAL]
# 	18 : ZonePercentage [NUMERICAL]
# 	16 : ZoneVariance [NUMERICAL]
# 	9 : LargeAreaHighGrayLevelEmphasis [NUMERICAL]
# 	5 : SizeZoneNonUniformity [NUMERICAL]
# 	3 : SizeZoneNonUniformityNormalized [NUMERICAL]
# 	1 : SmallAreaEmphasis [NUMERICAL]
#
# Attribute in nodes with depth <= 2:
# 	253 : SmallAreaHighGrayLevelEmphasis [NUMERICAL]
# 	241 : HighGrayLevelZoneEmphasis [NUMERICAL]
# 	170 : LowGrayLevelZoneEmphasis [NUMERICAL]
# 	112 : SmallAreaLowGrayLevelEmphasis [NUMERICAL]
# 	103 : ZoneEntropy [NUMERICAL]
# 	101 : LargeAreaLowGrayLevelEmphasis [NUMERICAL]
# 	93 : GrayLevelNonUniformityNormalized [NUMERICAL]
# 	85 : GrayLevelVariance [NUMERICAL]
# 	55 : GrayLevelNonUniformity [NUMERICAL]
# 	47 : ZonePercentage [NUMERICAL]
# 	47 : LargeAreaEmphasis [NUMERICAL]
# 	46 : ZoneVariance [NUMERICAL]
# 	23 : LargeAreaHighGrayLevelEmphasis [NUMERICAL]
# 	22 : SizeZoneNonUniformityNormalized [NUMERICAL]
# 	18 : SmallAreaEmphasis [NUMERICAL]
# 	18 : SizeZoneNonUniformity [NUMERICAL]
#
# Attribute in nodes with depth <= 3:
# 	294 : HighGrayLevelZoneEmphasis [NUMERICAL]
# 	281 : SmallAreaHighGrayLevelEmphasis [NUMERICAL]
# 	210 : LowGrayLevelZoneEmphasis [NUMERICAL]
# 	153 : SmallAreaLowGrayLevelEmphasis [NUMERICAL]
# 	148 : LargeAreaLowGrayLevelEmphasis [NUMERICAL]
# 	129 : ZoneEntropy [NUMERICAL]
# 	126 : GrayLevelNonUniformityNormalized [NUMERICAL]
# 	112 : GrayLevelVariance [NUMERICAL]
# 	82 : GrayLevelNonUniformity [NUMERICAL]
# 	71 : LargeAreaEmphasis [NUMERICAL]
# 	69 : ZoneVariance [NUMERICAL]
# 	69 : ZonePercentage [NUMERICAL]
# 	52 : SizeZoneNonUniformityNormalized [NUMERICAL]
# 	47 : SmallAreaEmphasis [NUMERICAL]
# 	40 : LargeAreaHighGrayLevelEmphasis [NUMERICAL]
# 	39 : SizeZoneNonUniformity [NUMERICAL]
#
# Attribute in nodes with depth <= 5:
# 	322 : HighGrayLevelZoneEmphasis [NUMERICAL]
# 	307 : SmallAreaHighGrayLevelEmphasis [NUMERICAL]
# 	249 : LowGrayLevelZoneEmphasis [NUMERICAL]
# 	187 : SmallAreaLowGrayLevelEmphasis [NUMERICAL]
# 	180 : LargeAreaLowGrayLevelEmphasis [NUMERICAL]
# 	163 : ZoneEntropy [NUMERICAL]
# 	147 : GrayLevelNonUniformityNormalized [NUMERICAL]
# 	144 : GrayLevelVariance [NUMERICAL]
# 	108 : GrayLevelNonUniformity [NUMERICAL]
# 	103 : LargeAreaEmphasis [NUMERICAL]
# 	94 : ZoneVariance [NUMERICAL]
# 	91 : ZonePercentage [NUMERICAL]
# 	80 : SizeZoneNonUniformityNormalized [NUMERICAL]
# 	70 : SmallAreaEmphasis [NUMERICAL]
# 	68 : LargeAreaHighGrayLevelEmphasis [NUMERICAL]
# 	58 : SizeZoneNonUniformity [NUMERICAL]
#
# Condition type in nodes:
# 	2413 : HigherCondition
# Condition type in nodes with depth <= 0:
# 	300 : HigherCondition
# Condition type in nodes with depth <= 1:
# 	845 : HigherCondition
# Condition type in nodes with depth <= 2:
# 	1434 : HigherCondition
# Condition type in nodes with depth <= 3:
# 	1922 : HigherCondition
# Condition type in nodes with depth <= 5:
# 	2371 : HigherCondition
# Node format: NOT_SET
#
# Training OOB:
# 	trees: 1, Out-of-bag evaluation: accuracy:0.881622 logloss:4.26678
# 	trees: 11, Out-of-bag evaluation: accuracy:0.890551 logloss:1.08612
# 	trees: 21, Out-of-bag evaluation: accuracy:0.953265 logloss:0.176642
# 	trees: 31, Out-of-bag evaluation: accuracy:0.963696 logloss:0.168321
# 	trees: 42, Out-of-bag evaluation: accuracy:0.944088 logloss:0.146185
# 	trees: 52, Out-of-bag evaluation: accuracy:0.952639 logloss:0.145371
# 	trees: 62, Out-of-bag evaluation: accuracy:0.934911 logloss:0.14844
# 	trees: 74, Out-of-bag evaluation: accuracy:0.933658 logloss:0.131684
# 	trees: 84, Out-of-bag evaluation: accuracy:0.933658 logloss:0.135207
# 	trees: 94, Out-of-bag evaluation: accuracy:0.933658 logloss:0.13431
# 	trees: 104, Out-of-bag evaluation: accuracy:0.933658 logloss:0.133708
# 	trees: 114, Out-of-bag evaluation: accuracy:0.942835 logloss:0.132422
# 	trees: 124, Out-of-bag evaluation: accuracy:0.942835 logloss:0.132365
# 	trees: 134, Out-of-bag evaluation: accuracy:0.933031 logloss:0.13066
# 	trees: 144, Out-of-bag evaluation: accuracy:0.934284 logloss:0.133353
# 	trees: 154, Out-of-bag evaluation: accuracy:0.933658 logloss:0.132037
# 	trees: 164, Out-of-bag evaluation: accuracy:0.934284 logloss:0.132258
# 	trees: 174, Out-of-bag evaluation: accuracy:0.944088 logloss:0.13333
# 	trees: 184, Out-of-bag evaluation: accuracy:0.944088 logloss:0.135173
# 	trees: 194, Out-of-bag evaluation: accuracy:0.934911 logloss:0.134406
# 	trees: 204, Out-of-bag evaluation: accuracy:0.934911 logloss:0.13403
# 	trees: 214, Out-of-bag evaluation: accuracy:0.934284 logloss:0.132589
# 	trees: 224, Out-of-bag evaluation: accuracy:0.933658 logloss:0.132438
# 	trees: 234, Out-of-bag evaluation: accuracy:0.934284 logloss:0.131774
# 	trees: 244, Out-of-bag evaluation: accuracy:0.933658 logloss:0.131399
# 	trees: 254, Out-of-bag evaluation: accuracy:0.934284 logloss:0.132335
# 	trees: 266, Out-of-bag evaluation: accuracy:0.933658 logloss:0.13269
# 	trees: 277, Out-of-bag evaluation: accuracy:0.933658 logloss:0.132954
# 	trees: 288, Out-of-bag evaluation: accuracy:0.933658 logloss:0.132767
# 	trees: 298, Out-of-bag evaluation: accuracy:0.934284 logloss:0.132274
# 	trees: 300, Out-of-bag evaluation: accuracy:0.934284 logloss:0.131901

# %%
# Model features
model.make_inspector().features()
# Out:
# ["GrayLevelNonUniformity" (1; #0),
#  "GrayLevelNonUniformityNormalized" (1; #1),
#  "GrayLevelVariance" (1; #2),
#  "HighGrayLevelZoneEmphasis" (1; #3),
#  "LargeAreaEmphasis" (1; #4),
#  "LargeAreaHighGrayLevelEmphasis" (1; #5),
#  "LargeAreaLowGrayLevelEmphasis" (1; #6),
#  "LowGrayLevelZoneEmphasis" (1; #7),
#  "SizeZoneNonUniformity" (1; #8),
#  "SizeZoneNonUniformityNormalized" (1; #9),
#  "SmallAreaEmphasis" (1; #10),
#  "SmallAreaHighGrayLevelEmphasis" (1; #11),
#  "SmallAreaLowGrayLevelEmphasis" (1; #12),
#  "ZoneEntropy" (1; #13),
#  "ZonePercentage" (1; #14),
#  "ZoneVariance" (1; #15)]

# %%
# Feature importance
model.make_inspector().variable_importances()
# Out:
# {'INV_MEAN_MIN_DEPTH': [("SmallAreaHighGrayLevelEmphasis" (1; #11),
#    0.32939713788110253),
#   ("HighGrayLevelZoneEmphasis" (1; #3), 0.3214401211998262),
#   ("LowGrayLevelZoneEmphasis" (1; #7), 0.2810458815668631),
#   ("SmallAreaLowGrayLevelEmphasis" (1; #12), 0.2612644811314909),
#   ("LargeAreaLowGrayLevelEmphasis" (1; #6), 0.25463332765487295),
#   ("ZoneEntropy" (1; #13), 0.23561803032388887),
#   ("GrayLevelVariance" (1; #2), 0.23419920112136952),
#   ("GrayLevelNonUniformity" (1; #0), 0.231819724949589),
#   ("GrayLevelNonUniformityNormalized" (1; #1), 0.22918984100574907),
#   ("ZonePercentage" (1; #14), 0.226537023624829),
#   ("LargeAreaEmphasis" (1; #4), 0.2232068916298456),
#   ("ZoneVariance" (1; #15), 0.22101608750480534),
#   ("LargeAreaHighGrayLevelEmphasis" (1; #5), 0.22088653354137344),
#   ("SizeZoneNonUniformityNormalized" (1; #9), 0.219508320570018),
#   ("SmallAreaEmphasis" (1; #10), 0.21879182477591202),
#   ("SizeZoneNonUniformity" (1; #8), 0.21874847781497844)],
#  'NUM_AS_ROOT': [("SmallAreaHighGrayLevelEmphasis" (1; #11), 86.0),
#   ("HighGrayLevelZoneEmphasis" (1; #3), 77.0),
#   ("LowGrayLevelZoneEmphasis" (1; #7), 45.0),
#   ("SmallAreaLowGrayLevelEmphasis" (1; #12), 31.0),
#   ("LargeAreaLowGrayLevelEmphasis" (1; #6), 23.0),
#   ("ZoneEntropy" (1; #13), 12.0),
#   ("ZonePercentage" (1; #14), 9.0),
#   ("GrayLevelVariance" (1; #2), 8.0),
#   ("GrayLevelNonUniformityNormalized" (1; #1), 4.0),
#   ("LargeAreaEmphasis" (1; #4), 2.0),
#   ("SizeZoneNonUniformity" (1; #8), 2.0),
#   ("SizeZoneNonUniformityNormalized" (1; #9), 1.0)],
#  'SUM_SCORE': [("SmallAreaHighGrayLevelEmphasis" (1; #11), 53410.33458627382),
#   ("HighGrayLevelZoneEmphasis" (1; #3), 45195.13278745073),
#   ("LowGrayLevelZoneEmphasis" (1; #7), 21758.313850375504),
#   ("SmallAreaLowGrayLevelEmphasis" (1; #12), 14156.666037342207),
#   ("LargeAreaLowGrayLevelEmphasis" (1; #6), 8861.10037934422),
#   ("ZoneEntropy" (1; #13), 7756.294854950778),
#   ("GrayLevelNonUniformityNormalized" (1; #1), 4764.971303302468),
#   ("GrayLevelVariance" (1; #2), 4008.9821375438723),
#   ("ZonePercentage" (1; #14), 2355.195079703345),
#   ("GrayLevelNonUniformity" (1; #0), 1953.723631245157),
#   ("LargeAreaEmphasis" (1; #4), 1799.610860743069),
#   ("ZoneVariance" (1; #15), 1414.4180791857843),
#   ("LargeAreaHighGrayLevelEmphasis" (1; #5), 825.2123031006174),
#   ("SizeZoneNonUniformity" (1; #8), 781.6641775481772),
#   ("SizeZoneNonUniformityNormalized" (1; #9), 638.8862961232682),
#   ("SmallAreaEmphasis" (1; #10), 369.0074863334324)],
#  'NUM_NODES': [("HighGrayLevelZoneEmphasis" (1; #3), 323.0),
#   ("SmallAreaHighGrayLevelEmphasis" (1; #11), 309.0),
#   ("LowGrayLevelZoneEmphasis" (1; #7), 250.0),
#   ("SmallAreaLowGrayLevelEmphasis" (1; #12), 194.0),
#   ("LargeAreaLowGrayLevelEmphasis" (1; #6), 185.0),
#   ("ZoneEntropy" (1; #13), 166.0),
#   ("GrayLevelNonUniformityNormalized" (1; #1), 150.0),
#   ("GrayLevelVariance" (1; #2), 145.0),
#   ("GrayLevelNonUniformity" (1; #0), 113.0),
#   ("LargeAreaEmphasis" (1; #4), 103.0),
#   ("ZoneVariance" (1; #15), 98.0),
#   ("ZonePercentage" (1; #14), 92.0),
#   ("SizeZoneNonUniformityNormalized" (1; #9), 82.0),
#   ("SmallAreaEmphasis" (1; #10), 72.0),
#   ("LargeAreaHighGrayLevelEmphasis" (1; #5), 69.0),
#   ("SizeZoneNonUniformity" (1; #8), 62.0)]}

# %%
# Model self evaluation
model.make_inspector().evaluation()
# Out:
# Evaluation(num_examples=849, accuracy=0.9342842404055486, loss=0.13190140645337686, rmse=None, ndcg=None, aucs=None, auuc=None, qini=None)

# %%
logs = model.make_inspector().training_logs()

plt.figure(figsize=(12, 4))
plt.subplot(1, 2, 1)
plt.plot([log.num_trees for log in logs], [log.evaluation.accuracy for log in logs])
plt.xlabel("Number of trees")
plt.ylabel("Accuracy (out-of-bag)")
plt.subplot(1, 2, 2)
plt.plot([log.num_trees for log in logs], [log.evaluation.loss for log in logs])
plt.xlabel("Number of trees")
plt.ylabel("Logloss (out-of-bag)")
plt.show()

# %% [markdown]
# Calculate the score of our hold-out validation dataset

# %%
predictions = model.predict(val_ds)
y_true      = validation_data["label"]

from sklearn.metrics import roc_auc_score
ROC_AUC = roc_auc_score(y_true, predictions)
print("The ROC AUC score is %.5f" % ROC_AUC )
# Out:
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 61ms/step
# The ROC AUC score is 1.00000

# %%
# Compute binary classification metrics with sklearn
import numpy as np
from sklearn.metrics import (
    accuracy_score,
    precision_score,
    recall_score,
    f1_score,
    roc_auc_score,
    average_precision_score,
    confusion_matrix,
    classification_report,
    matthews_corrcoef,
    log_loss,
    brier_score_loss,
)

# Get predictions (probabilities or class labels)
preds = model.predict(test_ds)
# If model outputs probabilities, convert to labels by threshold 0.5
if preds.ndim == 2:
    # For TFDF classification, preds may be class probabilities with shape (N, 2)
    if preds.shape[1] == 2:
        pos_probs = preds[:, 1]
    else:
        # If single-probability column (positive class)
        pos_probs = preds[:, -1]
    y_pred = (pos_probs >= 0.5).astype(int)
else:
    # Already class labels
    y_pred = preds.astype(int)
    pos_probs = None

# Ground truth labels (must be 0/1 integers)
y_true = test_data["label"].astype(int).to_numpy()

# Core metrics
metrics = {}
metrics["accuracy"] = accuracy_score(y_true, y_pred)
metrics["precision"] = precision_score(y_true, y_pred, zero_division=0)
metrics["recall"] = recall_score(y_true, y_pred, zero_division=0)
metrics["f1"] = f1_score(y_true, y_pred, zero_division=0)
metrics["mcc"] = matthews_corrcoef(y_true, y_pred)

# Probabilistic metrics (only if we have probabilities)
if pos_probs is not None:
    metrics["roc_auc"] = roc_auc_score(y_true, pos_probs)
    metrics["pr_auc"] = average_precision_score(y_true, pos_probs)
    metrics["log_loss"] = log_loss(y_true, pos_probs, labels=[0,1])
    metrics["brier_score"] = brier_score_loss(y_true, pos_probs)

# Confusion matrix and detailed report
cm = confusion_matrix(y_true, y_pred, labels=[0,1])
report = classification_report(y_true, y_pred, digits=4)

print("Sklearn binary metrics:")
for k, v in metrics.items():
    print(f"{k}: {v:.4f}")
print("\nConfusion matrix:\n", cm)
print("\nClassification report:\n", report)
# Out:
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 67ms/step
# Sklearn binary metrics:
# accuracy: 0.9795
# precision: 0.8421
# recall: 0.8889
# f1: 0.8649
# mcc: 0.8542
# roc_auc: 0.9913
# pr_auc: 0.9084
# log_loss: 0.0640
# brier_score: 0.0177
#
# Confusion matrix:
#  [[223   3]
#  [  2  16]]
#
# Classification report:
#                precision    recall  f1-score   support
#
#            0     0.9911    0.9867    0.9889       226
#            1     0.8421    0.8889    0.8649        18
#
#     accuracy                         0.9795       244
#    macro avg     0.9166    0.9378    0.9269       244
# weighted avg     0.9801    0.9795    0.9798       244
