# %%
# Import packages and modules
import numpy  as np
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow_decision_forests as tfdf

from sklearn.model_selection import train_test_split
# Out:
# 2026-08-15 05:17:29.471575: I tensorflow/core/util/port.cc:113] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2026-08-15 05:17:29.845081: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2026-08-15 05:17:34.559766: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
# Check the version of TensorFlow Decision Forests
print("Found TensorFlow Decision Forests v" + tfdf.__version__)
# Out:
# Found TensorFlow Decision Forests v1.9.1

# %%
datasetPath = 'dataset/firstorder/kernel5/dataset.csv'

# %%
# Parameters
datasetPath = "dataset/gldm/kernel5/1.dataset.csv"

# %%
# train/validation/test = 70/10/20
dataset = pd.read_csv(datasetPath)

train_data, temp_data = train_test_split(dataset, test_size=0.3, random_state=42)
validation_data, test_data = train_test_split(temp_data, test_size=2/3, random_state=42)

# %%
from sklearn.utils.class_weight import compute_class_weight

# tinh class weight tren tap train
classes = np.array([0, 1])
weights = compute_class_weight(class_weight="balanced", classes=classes, y=train_data["label"])
class_weight = {0: weights[0], 1: weights[1]}

# gan sample_weight cho tung dong
train_data["sample_weight"] = train_data["label"].map(class_weight)
validation_data["sample_weight"] = validation_data["label"].map(class_weight)
test_data["sample_weight"] = test_data["label"].map(class_weight)

# Convert the dataset into a TensorFlow dataset.
train_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    train_data, label="label", weight="sample_weight"
)         
val_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    validation_data, label="label", weight="sample_weight"
)
test_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    test_data, label="label", weight="sample_weight"
)
# Out:
# 2026-08-15 05:17:48.123549: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:984] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2026-08-15 05:17:48.125195: W tensorflow/core/common_runtime/gpu/gpu_device.cc:2251] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...

# %%
import keras

# %%
# %%time

# Train a Random Forest model.
model = tfdf.keras.RandomForestModel()

# Add evaluation metrics
model.compile(
    metrics=["accuracy"]
)
model.fit(x=train_ds)

# # Train a Gradient Boosted Trees model.
# model = tfdf.keras.GradientBoostedTreesModel(num_trees=1500)
# model.fit(train_ds)
# Out:
# Use /tmp/tmpdm7wq57z as temporary training directory
# Reading training dataset...
# Training dataset read in 0:00:02.575044. Found 849 examples.
# Training model...
# Model trained in 0:00:00.051027
# Compiling model...
# [INFO 26-08-15 05:17:50.9137 UTC kernel.cc:1233] Loading model from path /tmp/tmpdm7wq57z/model/ with prefix b13ecdb786874f01
# [INFO 26-08-15 05:17:50.9204 UTC decision_forest.cc:734] Model loaded with 300 root(s), 5212 node(s), and 14 input feature(s).
# [INFO 26-08-15 05:17:50.9204 UTC abstract_model.cc:1362] Engine "RandomForestOptPred" built
# [INFO 26-08-15 05:17:50.9205 UTC kernel.cc:1061] Use fast generic engine
# Model compiled.
# CPU times: user 5.48 s, sys: 90.8 ms, total: 5.57 s
# Wall time: 5.8 s

# %%
# Evaluate the model
evaluate = model.evaluate(val_ds, return_dict=True)
print()

for name, value in evaluate.items():
    print(f"{name}: {value:.4f}")
# Out:
# WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 1/1 [==============================] - ETA: 0s - loss: 0.0000e+00 - accuracy: 1.0000
# 1/1 [==============================] - 3s 3s/step - loss: 0.0000e+00 - accuracy: 1.0000
# loss: 0.0000
# accuracy: 1.0000

# %%
# Model Summary
model.summary()
# Out:
# Model: "random_forest_model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
# =================================================================
# Total params: 1 (1.00 Byte)
# Trainable params: 0 (0.00 Byte)
# Non-trainable params: 1 (1.00 Byte)
# _________________________________________________________________
# Type: "RANDOM_FOREST"
# Task: CLASSIFICATION
# Label: "__LABEL"
#
# Input Features (14):
# 	DependenceEntropy
# 	DependenceNonUniformity
# 	DependenceNonUniformityNormalized
# 	DependenceVariance
# 	GrayLevelNonUniformity
# 	GrayLevelVariance
# 	HighGrayLevelEmphasis
# 	LargeDependenceEmphasis
# 	LargeDependenceHighGrayLevelEmphasis
# 	LargeDependenceLowGrayLevelEmphasis
# 	LowGrayLevelEmphasis
# 	SmallDependenceEmphasis
# 	SmallDependenceHighGrayLevelEmphasis
# 	SmallDependenceLowGrayLevelEmphasis
#
# Trained with weights
#
# Variable Importance: INV_MEAN_MIN_DEPTH:
#     1. "SmallDependenceHighGrayLevelEmphasis"  0.357384 ################
#     2.                "HighGrayLevelEmphasis"  0.325193 ############
#     3.                 "LowGrayLevelEmphasis"  0.270502 ######
#     4.  "LargeDependenceLowGrayLevelEmphasis"  0.256303 ####
#     5.                    "DependenceEntropy"  0.245938 ###
#     6.  "SmallDependenceLowGrayLevelEmphasis"  0.240578 ###
#     7. "LargeDependenceHighGrayLevelEmphasis"  0.239454 ###
#     8.               "GrayLevelNonUniformity"  0.234544 ##
#     9.                    "GrayLevelVariance"  0.223946 #
#    10.              "SmallDependenceEmphasis"  0.217848
#    11.                   "DependenceVariance"  0.215390
#    12.    "DependenceNonUniformityNormalized"  0.213183
#    13.              "DependenceNonUniformity"  0.212704
#    14.              "LargeDependenceEmphasis"  0.211987
#
# Variable Importance: NUM_AS_ROOT:
#     1. "SmallDependenceHighGrayLevelEmphasis" 97.000000 ################
#     2.                "HighGrayLevelEmphasis" 77.000000 ############
#     3.                 "LowGrayLevelEmphasis" 45.000000 #######
#     4.  "LargeDependenceLowGrayLevelEmphasis" 38.000000 ######
#     5.               "GrayLevelNonUniformity" 13.000000 ##
#     6. "LargeDependenceHighGrayLevelEmphasis" 12.000000 #
#     7.                    "DependenceEntropy"  9.000000 #
#     8.  "SmallDependenceLowGrayLevelEmphasis"  7.000000 #
#     9.                    "GrayLevelVariance"  1.000000
#    10.              "SmallDependenceEmphasis"  1.000000
#
# Variable Importance: NUM_NODES:
#     1.                "HighGrayLevelEmphasis" 385.000000 ################
#     2. "SmallDependenceHighGrayLevelEmphasis" 325.000000 #############
#     3.                    "DependenceEntropy" 282.000000 ###########
#     4.                 "LowGrayLevelEmphasis" 255.000000 #########
#     5.               "GrayLevelNonUniformity" 190.000000 ######
#     6.  "LargeDependenceLowGrayLevelEmphasis" 188.000000 ######
#     7.  "SmallDependenceLowGrayLevelEmphasis" 177.000000 ######
#     8.                    "GrayLevelVariance" 171.000000 #####
#     9. "LargeDependenceHighGrayLevelEmphasis" 155.000000 #####
#    10.              "SmallDependenceEmphasis" 95.000000 ##
#    11.                   "DependenceVariance" 65.000000
#    12.    "DependenceNonUniformityNormalized" 62.000000
#    13.              "DependenceNonUniformity" 58.000000
#    14.              "LargeDependenceEmphasis" 48.000000
#
# Variable Importance: SUM_SCORE:
#     1. "SmallDependenceHighGrayLevelEmphasis" 57187.643028 ################
#     2.                "HighGrayLevelEmphasis" 45816.952348 ############
#     3.                 "LowGrayLevelEmphasis" 18898.212851 #####
#     4.  "LargeDependenceLowGrayLevelEmphasis" 14251.738712 ###
#     5.                    "DependenceEntropy" 11506.608692 ###
#     6.               "GrayLevelNonUniformity" 8447.107494 ##
#     7. "LargeDependenceHighGrayLevelEmphasis" 4503.224819 #
#     8.  "SmallDependenceLowGrayLevelEmphasis" 4086.410819 #
#     9.                    "GrayLevelVariance" 2243.707771
#    10.              "SmallDependenceEmphasis" 1274.809482
#    11.              "DependenceNonUniformity" 773.609595
#    12.    "DependenceNonUniformityNormalized" 749.443768
#    13.                   "DependenceVariance" 595.602299
#    14.              "LargeDependenceEmphasis" 399.148022
#
#
#
# Winner takes all: true
# Out-of-bag evaluation: accuracy:0.957239 logloss:0.149754
# Number of trees: 300
# Total number of nodes: 5212
#
# Number of nodes by tree:
# Count: 300 Average: 17.3733 StdDev: 3.26506
# Min: 9 Max: 27 Ignored: 0
# ----------------------------------------------
# [  9, 10)  1   0.33%   0.33%
# [ 10, 11)  0   0.00%   0.33%
# [ 11, 12) 15   5.00%   5.33% ##
# [ 12, 13)  0   0.00%   5.33%
# [ 13, 14) 32  10.67%  16.00% ####
# [ 14, 15)  0   0.00%  16.00%
# [ 15, 16) 53  17.67%  33.67% #######
# [ 16, 17)  0   0.00%  33.67%
# [ 17, 18) 65  21.67%  55.33% #########
# [ 18, 19)  0   0.00%  55.33%
# [ 19, 20) 75  25.00%  80.33% ##########
# [ 20, 21)  0   0.00%  80.33%
# [ 21, 22) 38  12.67%  93.00% #####
# [ 22, 23)  0   0.00%  93.00%
# [ 23, 24) 16   5.33%  98.33% ##
# [ 24, 25)  0   0.00%  98.33%
# [ 25, 26)  2   0.67%  99.00%
# [ 26, 27)  0   0.00%  99.00%
# [ 27, 27]  3   1.00% 100.00%
#
# Depth by leafs:
# Count: 2756 Average: 3.84615 StdDev: 1.43722
# Min: 1 Max: 9 Ignored: 0
# ----------------------------------------------
# [ 1, 2) 120   4.35%   4.35% ##
# [ 2, 3) 348  12.63%  16.98% #####
# [ 3, 4) 679  24.64%  41.62% #########
# [ 4, 5) 765  27.76%  69.38% ##########
# [ 5, 6) 515  18.69%  88.06% #######
# [ 6, 7) 228   8.27%  96.34% ###
# [ 7, 8)  70   2.54%  98.88% #
# [ 8, 9)  25   0.91%  99.78%
# [ 9, 9]   6   0.22% 100.00%
#
# Number of training obs by leaf:
# Count: 2756 Average: 92.4165 StdDev: 215.693
# Min: 5 Max: 790 Ignored: 0
# ----------------------------------------------
# [   5,  44) 2297  83.35%  83.35% ##########
# [  44,  83)   95   3.45%  86.79%
# [  83, 122)   34   1.23%  88.03%
# [ 122, 162)   18   0.65%  88.68%
# [ 162, 201)    6   0.22%  88.90%
# [ 201, 240)    3   0.11%  89.01%
# [ 240, 280)    2   0.07%  89.08%
# [ 280, 319)    0   0.00%  89.08%
# [ 319, 358)    2   0.07%  89.15%
# [ 358, 398)    0   0.00%  89.15%
# [ 398, 437)    1   0.04%  89.19%
# [ 437, 476)    2   0.07%  89.26%
# [ 476, 515)    0   0.00%  89.26%
# [ 515, 555)    3   0.11%  89.37%
# [ 555, 594)   12   0.44%  89.80%
# [ 594, 633)   12   0.44%  90.24%
# [ 633, 673)   31   1.12%  91.36%
# [ 673, 712)   54   1.96%  93.32%
# [ 712, 751)  143   5.19%  98.51% #
# [ 751, 790]   41   1.49% 100.00%
#
# Attribute in nodes:
# 	385 : HighGrayLevelEmphasis [NUMERICAL]
# 	325 : SmallDependenceHighGrayLevelEmphasis [NUMERICAL]
# 	282 : DependenceEntropy [NUMERICAL]
# 	255 : LowGrayLevelEmphasis [NUMERICAL]
# 	190 : GrayLevelNonUniformity [NUMERICAL]
# 	188 : LargeDependenceLowGrayLevelEmphasis [NUMERICAL]
# 	177 : SmallDependenceLowGrayLevelEmphasis [NUMERICAL]
# 	171 : GrayLevelVariance [NUMERICAL]
# 	155 : LargeDependenceHighGrayLevelEmphasis [NUMERICAL]
# 	95 : SmallDependenceEmphasis [NUMERICAL]
# 	65 : DependenceVariance [NUMERICAL]
# 	62 : DependenceNonUniformityNormalized [NUMERICAL]
# 	58 : DependenceNonUniformity [NUMERICAL]
# 	48 : LargeDependenceEmphasis [NUMERICAL]
#
# Attribute in nodes with depth <= 0:
# 	97 : SmallDependenceHighGrayLevelEmphasis [NUMERICAL]
# 	77 : HighGrayLevelEmphasis [NUMERICAL]
# 	45 : LowGrayLevelEmphasis [NUMERICAL]
# 	38 : LargeDependenceLowGrayLevelEmphasis [NUMERICAL]
# 	13 : GrayLevelNonUniformity [NUMERICAL]
# 	12 : LargeDependenceHighGrayLevelEmphasis [NUMERICAL]
# 	9 : DependenceEntropy [NUMERICAL]
# 	7 : SmallDependenceLowGrayLevelEmphasis [NUMERICAL]
# 	1 : SmallDependenceEmphasis [NUMERICAL]
# 	1 : GrayLevelVariance [NUMERICAL]
#
# Attribute in nodes with depth <= 1:
# 	199 : SmallDependenceHighGrayLevelEmphasis [NUMERICAL]
# 	195 : HighGrayLevelEmphasis [NUMERICAL]
# 	93 : LowGrayLevelEmphasis [NUMERICAL]
# 	62 : LargeDependenceLowGrayLevelEmphasis [NUMERICAL]
# 	57 : DependenceEntropy [NUMERICAL]
# 	52 : GrayLevelNonUniformity [NUMERICAL]
# 	44 : LargeDependenceHighGrayLevelEmphasis [NUMERICAL]
# 	33 : SmallDependenceLowGrayLevelEmphasis [NUMERICAL]
# 	14 : GrayLevelVariance [NUMERICAL]
# 	11 : SmallDependenceEmphasis [NUMERICAL]
# 	8 : DependenceNonUniformityNormalized [NUMERICAL]
# 	7 : DependenceNonUniformity [NUMERICAL]
# 	4 : DependenceVariance [NUMERICAL]
# 	1 : LargeDependenceEmphasis [NUMERICAL]
#
# Attribute in nodes with depth <= 2:
# 	291 : HighGrayLevelEmphasis [NUMERICAL]
# 	254 : SmallDependenceHighGrayLevelEmphasis [NUMERICAL]
# 	154 : LowGrayLevelEmphasis [NUMERICAL]
# 	147 : DependenceEntropy [NUMERICAL]
# 	100 : LargeDependenceLowGrayLevelEmphasis [NUMERICAL]
# 	99 : GrayLevelNonUniformity [NUMERICAL]
# 	97 : SmallDependenceLowGrayLevelEmphasis [NUMERICAL]
# 	90 : LargeDependenceHighGrayLevelEmphasis [NUMERICAL]
# 	52 : GrayLevelVariance [NUMERICAL]
# 	43 : SmallDependenceEmphasis [NUMERICAL]
# 	19 : DependenceNonUniformity [NUMERICAL]
# 	18 : DependenceVariance [NUMERICAL]
# 	17 : DependenceNonUniformityNormalized [NUMERICAL]
# 	11 : LargeDependenceEmphasis [NUMERICAL]
#
# Attribute in nodes with depth <= 3:
# 	355 : HighGrayLevelEmphasis [NUMERICAL]
# 	289 : SmallDependenceHighGrayLevelEmphasis [NUMERICAL]
# 	217 : DependenceEntropy [NUMERICAL]
# 	208 : LowGrayLevelEmphasis [NUMERICAL]
# 	146 : GrayLevelNonUniformity [NUMERICAL]
# 	141 : SmallDependenceLowGrayLevelEmphasis [NUMERICAL]
# 	141 : LargeDependenceLowGrayLevelEmphasis [NUMERICAL]
# 	125 : LargeDependenceHighGrayLevelEmphasis [NUMERICAL]
# 	104 : GrayLevelVariance [NUMERICAL]
# 	66 : SmallDependenceEmphasis [NUMERICAL]
# 	39 : DependenceVariance [NUMERICAL]
# 	38 : DependenceNonUniformityNormalized [NUMERICAL]
# 	37 : DependenceNonUniformity [NUMERICAL]
# 	31 : LargeDependenceEmphasis [NUMERICAL]
#
# Attribute in nodes with depth <= 5:
# 	380 : HighGrayLevelEmphasis [NUMERICAL]
# 	321 : SmallDependenceHighGrayLevelEmphasis [NUMERICAL]
# 	276 : DependenceEntropy [NUMERICAL]
# 	248 : LowGrayLevelEmphasis [NUMERICAL]
# 	186 : GrayLevelNonUniformity [NUMERICAL]
# 	185 : LargeDependenceLowGrayLevelEmphasis [NUMERICAL]
# 	175 : SmallDependenceLowGrayLevelEmphasis [NUMERICAL]
# 	162 : GrayLevelVariance [NUMERICAL]
# 	153 : LargeDependenceHighGrayLevelEmphasis [NUMERICAL]
# 	91 : SmallDependenceEmphasis [NUMERICAL]
# 	61 : DependenceVariance [NUMERICAL]
# 	56 : DependenceNonUniformity [NUMERICAL]
# 	55 : DependenceNonUniformityNormalized [NUMERICAL]
# 	48 : LargeDependenceEmphasis [NUMERICAL]
#
# Condition type in nodes:
# 	2456 : HigherCondition
# Condition type in nodes with depth <= 0:
# 	300 : HigherCondition
# Condition type in nodes with depth <= 1:
# 	780 : HigherCondition
# Condition type in nodes with depth <= 2:
# 	1392 : HigherCondition
# Condition type in nodes with depth <= 3:
# 	1937 : HigherCondition
# Condition type in nodes with depth <= 5:
# 	2397 : HigherCondition
# Node format: NOT_SET
#
# Training OOB:
# 	trees: 1, Out-of-bag evaluation: accuracy:0.975453 logloss:0.884755
# 	trees: 12, Out-of-bag evaluation: accuracy:0.935133 logloss:1.24239
# 	trees: 23, Out-of-bag evaluation: accuracy:0.956611 logloss:0.804349
# 	trees: 33, Out-of-bag evaluation: accuracy:0.965417 logloss:0.766601
# 	trees: 43, Out-of-bag evaluation: accuracy:0.945921 logloss:0.459247
# 	trees: 54, Out-of-bag evaluation: accuracy:0.936487 logloss:0.464401
# 	trees: 65, Out-of-bag evaluation: accuracy:0.955983 logloss:0.467449
# 	trees: 75, Out-of-bag evaluation: accuracy:0.946549 logloss:0.153219
# 	trees: 86, Out-of-bag evaluation: accuracy:0.937743 logloss:0.151226
# 	trees: 97, Out-of-bag evaluation: accuracy:0.956611 logloss:0.151272
# 	trees: 107, Out-of-bag evaluation: accuracy:0.966673 logloss:0.154278
# 	trees: 117, Out-of-bag evaluation: accuracy:0.966045 logloss:0.151637
# 	trees: 127, Out-of-bag evaluation: accuracy:0.965417 logloss:0.149971
# 	trees: 138, Out-of-bag evaluation: accuracy:0.966673 logloss:0.145801
# 	trees: 149, Out-of-bag evaluation: accuracy:0.955983 logloss:0.145517
# 	trees: 159, Out-of-bag evaluation: accuracy:0.956611 logloss:0.146805
# 	trees: 171, Out-of-bag evaluation: accuracy:0.955983 logloss:0.149827
# 	trees: 182, Out-of-bag evaluation: accuracy:0.955983 logloss:0.148968
# 	trees: 192, Out-of-bag evaluation: accuracy:0.955983 logloss:0.148395
# 	trees: 202, Out-of-bag evaluation: accuracy:0.956611 logloss:0.14854
# 	trees: 212, Out-of-bag evaluation: accuracy:0.956611 logloss:0.149378
# 	trees: 222, Out-of-bag evaluation: accuracy:0.956611 logloss:0.149369
# 	trees: 233, Out-of-bag evaluation: accuracy:0.957239 logloss:0.148892
# 	trees: 244, Out-of-bag evaluation: accuracy:0.957239 logloss:0.148742
# 	trees: 254, Out-of-bag evaluation: accuracy:0.957239 logloss:0.149269
# 	trees: 264, Out-of-bag evaluation: accuracy:0.957239 logloss:0.146968
# 	trees: 274, Out-of-bag evaluation: accuracy:0.957239 logloss:0.148631
# 	trees: 284, Out-of-bag evaluation: accuracy:0.957239 logloss:0.150563
# 	trees: 294, Out-of-bag evaluation: accuracy:0.957239 logloss:0.149437
# 	trees: 300, Out-of-bag evaluation: accuracy:0.957239 logloss:0.149754

# %%
# Model features
model.make_inspector().features()
# Out:
# ["DependenceEntropy" (1; #0),
#  "DependenceNonUniformity" (1; #1),
#  "DependenceNonUniformityNormalized" (1; #2),
#  "DependenceVariance" (1; #3),
#  "GrayLevelNonUniformity" (1; #4),
#  "GrayLevelVariance" (1; #5),
#  "HighGrayLevelEmphasis" (1; #6),
#  "LargeDependenceEmphasis" (1; #7),
#  "LargeDependenceHighGrayLevelEmphasis" (1; #8),
#  "LargeDependenceLowGrayLevelEmphasis" (1; #9),
#  "LowGrayLevelEmphasis" (1; #10),
#  "SmallDependenceEmphasis" (1; #11),
#  "SmallDependenceHighGrayLevelEmphasis" (1; #12),
#  "SmallDependenceLowGrayLevelEmphasis" (1; #13)]

# %%
# Feature importance
model.make_inspector().variable_importances()
# Out:
# {'INV_MEAN_MIN_DEPTH': [("SmallDependenceHighGrayLevelEmphasis" (1; #12),
#    0.3573839069578429),
#   ("HighGrayLevelEmphasis" (1; #6), 0.32519298557394544),
#   ("LowGrayLevelEmphasis" (1; #10), 0.2705015926435577),
#   ("LargeDependenceLowGrayLevelEmphasis" (1; #9), 0.2563025837350235),
#   ("DependenceEntropy" (1; #0), 0.24593776704368303),
#   ("SmallDependenceLowGrayLevelEmphasis" (1; #13), 0.24057824820541182),
#   ("LargeDependenceHighGrayLevelEmphasis" (1; #8), 0.23945369313698267),
#   ("GrayLevelNonUniformity" (1; #4), 0.23454419736640386),
#   ("GrayLevelVariance" (1; #5), 0.22394552967255602),
#   ("SmallDependenceEmphasis" (1; #11), 0.21784755444538512),
#   ("DependenceVariance" (1; #3), 0.21539015451579815),
#   ("DependenceNonUniformityNormalized" (1; #2), 0.21318328948583418),
#   ("DependenceNonUniformity" (1; #1), 0.21270429212541647),
#   ("LargeDependenceEmphasis" (1; #7), 0.2119869905465566)],
#  'SUM_SCORE': [("SmallDependenceHighGrayLevelEmphasis" (1; #12),
#    57187.64302775245),
#   ("HighGrayLevelEmphasis" (1; #6), 45816.95234786168),
#   ("LowGrayLevelEmphasis" (1; #10), 18898.212851469834),
#   ("LargeDependenceLowGrayLevelEmphasis" (1; #9), 14251.738711543607),
#   ("DependenceEntropy" (1; #0), 11506.60869233928),
#   ("GrayLevelNonUniformity" (1; #4), 8447.107494027568),
#   ("LargeDependenceHighGrayLevelEmphasis" (1; #8), 4503.224818746362),
#   ("SmallDependenceLowGrayLevelEmphasis" (1; #13), 4086.4108188202517),
#   ("GrayLevelVariance" (1; #5), 2243.7077705834336),
#   ("SmallDependenceEmphasis" (1; #11), 1274.8094824171978),
#   ("DependenceNonUniformity" (1; #1), 773.6095954701902),
#   ("DependenceNonUniformityNormalized" (1; #2), 749.4437684583564),
#   ("DependenceVariance" (1; #3), 595.6022990763745),
#   ("LargeDependenceEmphasis" (1; #7), 399.148021781109)],
#  'NUM_AS_ROOT': [("SmallDependenceHighGrayLevelEmphasis" (1; #12), 97.0),
#   ("HighGrayLevelEmphasis" (1; #6), 77.0),
#   ("LowGrayLevelEmphasis" (1; #10), 45.0),
#   ("LargeDependenceLowGrayLevelEmphasis" (1; #9), 38.0),
#   ("GrayLevelNonUniformity" (1; #4), 13.0),
#   ("LargeDependenceHighGrayLevelEmphasis" (1; #8), 12.0),
#   ("DependenceEntropy" (1; #0), 9.0),
#   ("SmallDependenceLowGrayLevelEmphasis" (1; #13), 7.0),
#   ("GrayLevelVariance" (1; #5), 1.0),
#   ("SmallDependenceEmphasis" (1; #11), 1.0)],
#  'NUM_NODES': [("HighGrayLevelEmphasis" (1; #6), 385.0),
#   ("SmallDependenceHighGrayLevelEmphasis" (1; #12), 325.0),
#   ("DependenceEntropy" (1; #0), 282.0),
#   ("LowGrayLevelEmphasis" (1; #10), 255.0),
#   ("GrayLevelNonUniformity" (1; #4), 190.0),
#   ("LargeDependenceLowGrayLevelEmphasis" (1; #9), 188.0),
#   ("SmallDependenceLowGrayLevelEmphasis" (1; #13), 177.0),
#   ("GrayLevelVariance" (1; #5), 171.0),
#   ("LargeDependenceHighGrayLevelEmphasis" (1; #8), 155.0),
#   ("SmallDependenceEmphasis" (1; #11), 95.0),
#   ("DependenceVariance" (1; #3), 65.0),
#   ("DependenceNonUniformityNormalized" (1; #2), 62.0),
#   ("DependenceNonUniformity" (1; #1), 58.0),
#   ("LargeDependenceEmphasis" (1; #7), 48.0)]}

# %%
# Model self evaluation
model.make_inspector().evaluation()
# Out:
# Evaluation(num_examples=849, accuracy=0.957239025811295, loss=0.1497538574247368, rmse=None, ndcg=None, aucs=None, auuc=None, qini=None)

# %%
logs = model.make_inspector().training_logs()

plt.figure(figsize=(12, 4))
plt.subplot(1, 2, 1)
plt.plot([log.num_trees for log in logs], [log.evaluation.accuracy for log in logs])
plt.xlabel("Number of trees")
plt.ylabel("Accuracy (out-of-bag)")
plt.subplot(1, 2, 2)
plt.plot([log.num_trees for log in logs], [log.evaluation.loss for log in logs])
plt.xlabel("Number of trees")
plt.ylabel("Logloss (out-of-bag)")
plt.show()

# %% [markdown]
# Calculate the score of our hold-out validation dataset

# %%
predictions = model.predict(val_ds)
y_true      = validation_data["label"]

from sklearn.metrics import roc_auc_score
ROC_AUC = roc_auc_score(y_true, predictions)
print("The ROC AUC score is %.5f" % ROC_AUC )
# Out:
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 63ms/step
# The ROC AUC score is 1.00000

# %%
# Compute binary classification metrics with sklearn
import numpy as np
from sklearn.metrics import (
    accuracy_score,
    precision_score,
    recall_score,
    f1_score,
    roc_auc_score,
    average_precision_score,
    confusion_matrix,
    classification_report,
    matthews_corrcoef,
    log_loss,
    brier_score_loss,
)

# Get predictions (probabilities or class labels)
preds = model.predict(test_ds)
# If model outputs probabilities, convert to labels by threshold 0.5
if preds.ndim == 2:
    # For TFDF classification, preds may be class probabilities with shape (N, 2)
    if preds.shape[1] == 2:
        pos_probs = preds[:, 1]
    else:
        # If single-probability column (positive class)
        pos_probs = preds[:, -1]
    y_pred = (pos_probs >= 0.5).astype(int)
else:
    # Already class labels
    y_pred = preds.astype(int)
    pos_probs = None

# Ground truth labels (must be 0/1 integers)
y_true = test_data["label"].astype(int).to_numpy()

# Core metrics
metrics = {}
metrics["accuracy"] = accuracy_score(y_true, y_pred)
metrics["precision"] = precision_score(y_true, y_pred, zero_division=0)
metrics["recall"] = recall_score(y_true, y_pred, zero_division=0)
metrics["f1"] = f1_score(y_true, y_pred, zero_division=0)
metrics["mcc"] = matthews_corrcoef(y_true, y_pred)

# Probabilistic metrics (only if we have probabilities)
if pos_probs is not None:
    metrics["roc_auc"] = roc_auc_score(y_true, pos_probs)
    metrics["pr_auc"] = average_precision_score(y_true, pos_probs)
    metrics["log_loss"] = log_loss(y_true, pos_probs, labels=[0,1])
    metrics["brier_score"] = brier_score_loss(y_true, pos_probs)

# Confusion matrix and detailed report
cm = confusion_matrix(y_true, y_pred, labels=[0,1])
report = classification_report(y_true, y_pred, digits=4)

print("Sklearn binary metrics:")
for k, v in metrics.items():
    print(f"{k}: {v:.4f}")
print("\nConfusion matrix:\n", cm)
print("\nClassification report:\n", report)
# Out:
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 65ms/step
# Sklearn binary metrics:
# accuracy: 0.9877
# precision: 0.8571
# recall: 0.9231
# f1: 0.8889
# mcc: 0.8831
# roc_auc: 0.9947
# pr_auc: 0.8266
# log_loss: 0.0829
# brier_score: 0.0111
#
# Confusion matrix:
#  [[229   2]
#  [  1  12]]
#
# Classification report:
#                precision    recall  f1-score   support
#
#            0     0.9957    0.9913    0.9935       231
#            1     0.8571    0.9231    0.8889        13
#
#     accuracy                         0.9877       244
#    macro avg     0.9264    0.9572    0.9412       244
# weighted avg     0.9883    0.9877    0.9879       244
