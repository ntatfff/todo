# %%
# Import packages and modules
import numpy  as np
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow_decision_forests as tfdf

from sklearn.model_selection import train_test_split
# Out:
# 2026-08-15 05:02:56.535192: I tensorflow/core/util/port.cc:113] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2026-08-15 05:02:56.877738: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2026-08-15 05:03:01.689198: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
# Check the version of TensorFlow Decision Forests
print("Found TensorFlow Decision Forests v" + tfdf.__version__)
# Out:
# Found TensorFlow Decision Forests v1.9.1

# %%
datasetPath = 'dataset/firstorder/kernel5/dataset.csv'

# %%
# Parameters
datasetPath = "dataset/gldm/kernel5/1.dataset.csv"

# %%
# train/validation/test = 70/10/20
dataset = pd.read_csv(datasetPath)

train_data, temp_data = train_test_split(dataset, test_size=0.3, random_state=42)
validation_data, test_data = train_test_split(temp_data, test_size=2/3, random_state=42)

# %%
from sklearn.utils.class_weight import compute_class_weight

# tinh class weight tren tap train
classes = np.array([0, 1])
weights = compute_class_weight(class_weight="balanced", classes=classes, y=train_data["label"])
class_weight = {0: weights[0], 1: weights[1]}

# gan sample_weight cho tung dong
train_data["sample_weight"] = train_data["label"].map(class_weight)
validation_data["sample_weight"] = validation_data["label"].map(class_weight)
test_data["sample_weight"] = test_data["label"].map(class_weight)

# Convert the dataset into a TensorFlow dataset.
train_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    train_data, label="label", weight="sample_weight"
)         
val_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    validation_data, label="label", weight="sample_weight"
)
test_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    test_data, label="label", weight="sample_weight"
)
# Out:
# 2026-08-15 05:03:14.952316: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:984] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2026-08-15 05:03:14.954197: W tensorflow/core/common_runtime/gpu/gpu_device.cc:2251] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...

# %%
import keras

# %%
# %%time

# Train a Gradient Boosted Trees model.
model = tfdf.keras.GradientBoostedTreesModel()

# Add evaluation metrics
model.compile(
    metrics=["accuracy"]
)
model.fit(x=train_ds)

# # Train a Gradient Boosted Trees model.
# model = tfdf.keras.GradientBoostedTreesModel(num_trees=1500)
# model.fit(train_ds)
# Out:
# Use /tmp/tmpl6gab6ti as temporary training directory
# Reading training dataset...
# [WARNING 26-08-15 05:03:15.1167 UTC gradient_boosted_trees.cc:1840] "goss_alpha" set but "sampling_method" not equal to "GOSS".
# [WARNING 26-08-15 05:03:15.1171 UTC gradient_boosted_trees.cc:1851] "goss_beta" set but "sampling_method" not equal to "GOSS".
# [WARNING 26-08-15 05:03:15.1171 UTC gradient_boosted_trees.cc:1865] "selective_gradient_boosting_ratio" set but "sampling_method" not equal to "SELGB".
# Training dataset read in 0:00:03.490986. Found 849 examples.
# Training model...
# Model trained in 0:00:00.153370
# Compiling model...
# [INFO 26-08-15 05:03:18.8026 UTC kernel.cc:1233] Loading model from path /tmp/tmpl6gab6ti/model/ with prefix c31e3d4284bb48e1
# [INFO 26-08-15 05:03:18.8039 UTC quick_scorer_extended.cc:911] The binary was compiled without AVX2 support, but your CPU supports it. Enable it for faster model inference.
# [INFO 26-08-15 05:03:18.8039 UTC abstract_model.cc:1362] Engine "GradientBoostedTreesQuickScorerExtended" built
# [INFO 26-08-15 05:03:18.8039 UTC kernel.cc:1061] Use fast generic engine
# Model compiled.
# CPU times: user 5.85 s, sys: 185 ms, total: 6.03 s
# Wall time: 6.89 s

# %%
# Evaluate the model
evaluate = model.evaluate(val_ds, return_dict=True)
print()

for name, value in evaluate.items():
    print(f"{name}: {value:.4f}")
# Out:
# WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 1/1 [==============================] - ETA: 0s - loss: 0.0000e+00 - accuracy: 1.0000
# 1/1 [==============================] - 3s 3s/step - loss: 0.0000e+00 - accuracy: 1.0000
# loss: 0.0000
# accuracy: 1.0000

# %%
# Model Summary
model.summary()
# Out:
# Model: "gradient_boosted_trees_model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
# =================================================================
# Total params: 1 (1.00 Byte)
# Trainable params: 0 (0.00 Byte)
# Non-trainable params: 1 (1.00 Byte)
# _________________________________________________________________
# Type: "GRADIENT_BOOSTED_TREES"
# Task: CLASSIFICATION
# Label: "__LABEL"
#
# Input Features (14):
# 	DependenceEntropy
# 	DependenceNonUniformity
# 	DependenceNonUniformityNormalized
# 	DependenceVariance
# 	GrayLevelNonUniformity
# 	GrayLevelVariance
# 	HighGrayLevelEmphasis
# 	LargeDependenceEmphasis
# 	LargeDependenceHighGrayLevelEmphasis
# 	LargeDependenceLowGrayLevelEmphasis
# 	LowGrayLevelEmphasis
# 	SmallDependenceEmphasis
# 	SmallDependenceHighGrayLevelEmphasis
# 	SmallDependenceLowGrayLevelEmphasis
#
# Trained with weights
#
# Variable Importance: INV_MEAN_MIN_DEPTH:
#     1. "SmallDependenceHighGrayLevelEmphasis"  1.000000 ################
#     2.                 "LowGrayLevelEmphasis"  0.377682 ###
#     3.                "HighGrayLevelEmphasis"  0.305614 ##
#     4. "LargeDependenceHighGrayLevelEmphasis"  0.231014
#     5.                    "DependenceEntropy"  0.215526
#     6.  "SmallDependenceLowGrayLevelEmphasis"  0.208474
#     7.              "SmallDependenceEmphasis"  0.200619
#     8.                    "GrayLevelVariance"  0.200234
#     9.               "GrayLevelNonUniformity"  0.196497
#    10.              "LargeDependenceEmphasis"  0.196317
#    11.    "DependenceNonUniformityNormalized"  0.196194
#    12.  "LargeDependenceLowGrayLevelEmphasis"  0.195934
#    13.              "DependenceNonUniformity"  0.195123
#
# Variable Importance: NUM_AS_ROOT:
#     1. "SmallDependenceHighGrayLevelEmphasis" 11.000000
#
# Variable Importance: NUM_NODES:
#     1.                "HighGrayLevelEmphasis" 27.000000 ################
#     2.                 "LowGrayLevelEmphasis" 23.000000 #############
#     3.                    "DependenceEntropy" 16.000000 #########
#     4. "LargeDependenceHighGrayLevelEmphasis" 16.000000 #########
#     5. "SmallDependenceHighGrayLevelEmphasis" 16.000000 #########
#     6.              "SmallDependenceEmphasis"  9.000000 ####
#     7.                    "GrayLevelVariance"  7.000000 ###
#     8.  "SmallDependenceLowGrayLevelEmphasis"  6.000000 ###
#     9.    "DependenceNonUniformityNormalized"  3.000000 #
#    10.              "LargeDependenceEmphasis"  3.000000 #
#    11.               "GrayLevelNonUniformity"  2.000000
#    12.  "LargeDependenceLowGrayLevelEmphasis"  2.000000
#    13.              "DependenceNonUniformity"  1.000000
#
# Variable Importance: SUM_SCORE:
#     1. "SmallDependenceHighGrayLevelEmphasis" 810.576147 ################
#     2.                 "LowGrayLevelEmphasis" 41.696502
#     3.                    "DependenceEntropy" 28.015490
#     4.                "HighGrayLevelEmphasis" 11.809828
#     5.  "SmallDependenceLowGrayLevelEmphasis"  9.300005
#     6. "LargeDependenceHighGrayLevelEmphasis"  7.734163
#     7.    "DependenceNonUniformityNormalized"  0.613502
#     8.              "SmallDependenceEmphasis"  0.368895
#     9.                    "GrayLevelVariance"  0.108351
#    10.               "GrayLevelNonUniformity"  0.032677
#    11.  "LargeDependenceLowGrayLevelEmphasis"  0.013856
#    12.              "LargeDependenceEmphasis"  0.001789
#    13.              "DependenceNonUniformity"  0.000000
#
#
#
# Loss: BINOMIAL_LOG_LIKELIHOOD
# Validation loss value: 1.08611
# Number of trees per iteration: 1
# Node format: NOT_SET
# Number of trees: 11
# Total number of nodes: 273
#
# Number of nodes by tree:
# Count: 11 Average: 24.8182 StdDev: 3.00963
# Min: 19 Max: 29 Ignored: 0
# ----------------------------------------------
# [ 19, 20) 1   9.09%   9.09% ###
# [ 20, 21) 0   0.00%   9.09%
# [ 21, 22) 1   9.09%  18.18% ###
# [ 22, 23) 0   0.00%  18.18%
# [ 23, 24) 2  18.18%  36.36% #######
# [ 24, 25) 0   0.00%  36.36%
# [ 25, 26) 3  27.27%  63.64% ##########
# [ 26, 27) 0   0.00%  63.64%
# [ 27, 28) 2  18.18%  81.82% #######
# [ 28, 29) 0   0.00%  81.82%
# [ 29, 29] 2  18.18% 100.00% #######
#
# Depth by leafs:
# Count: 142 Average: 4.15493 StdDev: 1.07005
# Min: 2 Max: 5 Ignored: 0
# ----------------------------------------------
# [ 2, 3) 18  12.68%  12.68% ##
# [ 3, 4) 18  12.68%  25.35% ##
# [ 4, 5) 30  21.13%  46.48% ####
# [ 5, 5] 76  53.52% 100.00% ##########
#
# Number of training obs by leaf:
# Count: 142 Average: 60.3451 StdDev: 168.799
# Min: 5 Max: 679 Ignored: 0
# ----------------------------------------------
# [   5,  38) 128  90.14%  90.14% ##########
# [  38,  72)   1   0.70%  90.85%
# [  72, 106)   0   0.00%  90.85%
# [ 106, 140)   0   0.00%  90.85%
# [ 140, 173)   0   0.00%  90.85%
# [ 173, 207)   1   0.70%  91.55%
# [ 207, 241)   0   0.00%  91.55%
# [ 241, 275)   1   0.70%  92.25%
# [ 275, 308)   0   0.00%  92.25%
# [ 308, 342)   0   0.00%  92.25%
# [ 342, 376)   0   0.00%  92.25%
# [ 376, 410)   1   0.70%  92.96%
# [ 410, 443)   0   0.00%  92.96%
# [ 443, 477)   0   0.00%  92.96%
# [ 477, 511)   0   0.00%  92.96%
# [ 511, 545)   1   0.70%  93.66%
# [ 545, 578)   0   0.00%  93.66%
# [ 578, 612)   0   0.00%  93.66%
# [ 612, 646)   1   0.70%  94.37%
# [ 646, 679]   8   5.63% 100.00% #
#
# Attribute in nodes:
# 	27 : HighGrayLevelEmphasis [NUMERICAL]
# 	23 : LowGrayLevelEmphasis [NUMERICAL]
# 	16 : SmallDependenceHighGrayLevelEmphasis [NUMERICAL]
# 	16 : LargeDependenceHighGrayLevelEmphasis [NUMERICAL]
# 	16 : DependenceEntropy [NUMERICAL]
# 	9 : SmallDependenceEmphasis [NUMERICAL]
# 	7 : GrayLevelVariance [NUMERICAL]
# 	6 : SmallDependenceLowGrayLevelEmphasis [NUMERICAL]
# 	3 : LargeDependenceEmphasis [NUMERICAL]
# 	3 : DependenceNonUniformityNormalized [NUMERICAL]
# 	2 : LargeDependenceLowGrayLevelEmphasis [NUMERICAL]
# 	2 : GrayLevelNonUniformity [NUMERICAL]
# 	1 : DependenceNonUniformity [NUMERICAL]
#
# Attribute in nodes with depth <= 0:
# 	11 : SmallDependenceHighGrayLevelEmphasis [NUMERICAL]
#
# Attribute in nodes with depth <= 1:
# 	13 : LowGrayLevelEmphasis [NUMERICAL]
# 	11 : SmallDependenceHighGrayLevelEmphasis [NUMERICAL]
# 	4 : LargeDependenceHighGrayLevelEmphasis [NUMERICAL]
# 	3 : SmallDependenceLowGrayLevelEmphasis [NUMERICAL]
# 	2 : HighGrayLevelEmphasis [NUMERICAL]
#
# Attribute in nodes with depth <= 2:
# 	17 : HighGrayLevelEmphasis [NUMERICAL]
# 	16 : LowGrayLevelEmphasis [NUMERICAL]
# 	13 : SmallDependenceHighGrayLevelEmphasis [NUMERICAL]
# 	7 : LargeDependenceHighGrayLevelEmphasis [NUMERICAL]
# 	4 : SmallDependenceLowGrayLevelEmphasis [NUMERICAL]
# 	1 : SmallDependenceEmphasis [NUMERICAL]
# 	1 : LargeDependenceEmphasis [NUMERICAL]
#
# Attribute in nodes with depth <= 3:
# 	22 : HighGrayLevelEmphasis [NUMERICAL]
# 	19 : LowGrayLevelEmphasis [NUMERICAL]
# 	14 : SmallDependenceHighGrayLevelEmphasis [NUMERICAL]
# 	13 : LargeDependenceHighGrayLevelEmphasis [NUMERICAL]
# 	13 : DependenceEntropy [NUMERICAL]
# 	5 : SmallDependenceLowGrayLevelEmphasis [NUMERICAL]
# 	2 : SmallDependenceEmphasis [NUMERICAL]
# 	2 : LargeDependenceEmphasis [NUMERICAL]
# 	1 : GrayLevelVariance [NUMERICAL]
# 	1 : GrayLevelNonUniformity [NUMERICAL]
# 	1 : DependenceNonUniformity [NUMERICAL]
#
# Attribute in nodes with depth <= 5:
# 	27 : HighGrayLevelEmphasis [NUMERICAL]
# 	23 : LowGrayLevelEmphasis [NUMERICAL]
# 	16 : SmallDependenceHighGrayLevelEmphasis [NUMERICAL]
# 	16 : LargeDependenceHighGrayLevelEmphasis [NUMERICAL]
# 	16 : DependenceEntropy [NUMERICAL]
# 	9 : SmallDependenceEmphasis [NUMERICAL]
# 	7 : GrayLevelVariance [NUMERICAL]
# 	6 : SmallDependenceLowGrayLevelEmphasis [NUMERICAL]
# 	3 : LargeDependenceEmphasis [NUMERICAL]
# 	3 : DependenceNonUniformityNormalized [NUMERICAL]
# 	2 : LargeDependenceLowGrayLevelEmphasis [NUMERICAL]
# 	2 : GrayLevelNonUniformity [NUMERICAL]
# 	1 : DependenceNonUniformity [NUMERICAL]
#
# Condition type in nodes:
# 	131 : HigherCondition
# Condition type in nodes with depth <= 0:
# 	11 : HigherCondition
# Condition type in nodes with depth <= 1:
# 	33 : HigherCondition
# Condition type in nodes with depth <= 2:
# 	59 : HigherCondition
# Condition type in nodes with depth <= 3:
# 	93 : HigherCondition
# Condition type in nodes with depth <= 5:
# 	131 : HigherCondition
#
# Training logs:
# Number of iteration to final model: 11
# 	Iter:1 train-loss:1.201921 valid-loss:1.286741  train-accuracy:0.991735 valid-accuracy:0.778451
# 	Iter:2 train-loss:1.050408 valid-loss:1.213817  train-accuracy:0.994490 valid-accuracy:0.778451
# 	Iter:3 train-loss:0.924382 valid-loss:1.160210  train-accuracy:0.992424 valid-accuracy:0.778451
# 	Iter:4 train-loss:0.817776 valid-loss:1.121721  train-accuracy:0.994490 valid-accuracy:0.778451
# 	Iter:5 train-loss:0.726458 valid-loss:1.095045  train-accuracy:0.994490 valid-accuracy:0.778451
# 	Iter:6 train-loss:0.648081 valid-loss:1.078315  train-accuracy:0.994490 valid-accuracy:0.778451
# 	Iter:16 train-loss:0.226603 valid-loss:1.191043  train-accuracy:0.997245 valid-accuracy:0.785589
# 	Iter:26 train-loss:0.092195 valid-loss:1.572685  train-accuracy:0.997245 valid-accuracy:0.778451
# 	Iter:36 train-loss:0.039923 valid-loss:2.027405  train-accuracy:0.998622 valid-accuracy:0.785589

# %%
# Model features
model.make_inspector().features()
# Out:
# ["DependenceEntropy" (1; #0),
#  "DependenceNonUniformity" (1; #1),
#  "DependenceNonUniformityNormalized" (1; #2),
#  "DependenceVariance" (1; #3),
#  "GrayLevelNonUniformity" (1; #4),
#  "GrayLevelVariance" (1; #5),
#  "HighGrayLevelEmphasis" (1; #6),
#  "LargeDependenceEmphasis" (1; #7),
#  "LargeDependenceHighGrayLevelEmphasis" (1; #8),
#  "LargeDependenceLowGrayLevelEmphasis" (1; #9),
#  "LowGrayLevelEmphasis" (1; #10),
#  "SmallDependenceEmphasis" (1; #11),
#  "SmallDependenceHighGrayLevelEmphasis" (1; #12),
#  "SmallDependenceLowGrayLevelEmphasis" (1; #13)]

# %%
# Feature importance
model.make_inspector().variable_importances()
# Out:
# {'INV_MEAN_MIN_DEPTH': [("SmallDependenceHighGrayLevelEmphasis" (1; #12), 1.0),
#   ("LowGrayLevelEmphasis" (1; #10), 0.37768164774523494),
#   ("HighGrayLevelEmphasis" (1; #6), 0.305614214442499),
#   ("LargeDependenceHighGrayLevelEmphasis" (1; #8), 0.2310137315854439),
#   ("DependenceEntropy" (1; #0), 0.21552591736183177),
#   ("SmallDependenceLowGrayLevelEmphasis" (1; #13), 0.20847388633114863),
#   ("SmallDependenceEmphasis" (1; #11), 0.20061874603718308),
#   ("GrayLevelVariance" (1; #5), 0.20023410047408075),
#   ("GrayLevelNonUniformity" (1; #4), 0.19649692611066005),
#   ("LargeDependenceEmphasis" (1; #7), 0.19631708599904318),
#   ("DependenceNonUniformityNormalized" (1; #2), 0.1961939572047365),
#   ("LargeDependenceLowGrayLevelEmphasis" (1; #9), 0.1959340990459831),
#   ("DependenceNonUniformity" (1; #1), 0.19512313260256917)],
#  'SUM_SCORE': [("SmallDependenceHighGrayLevelEmphasis" (1; #12),
#    810.576146816589),
#   ("LowGrayLevelEmphasis" (1; #10), 41.696501591152334),
#   ("DependenceEntropy" (1; #0), 28.015489844243362),
#   ("HighGrayLevelEmphasis" (1; #6), 11.809827608442799),
#   ("SmallDependenceLowGrayLevelEmphasis" (1; #13), 9.30000496743048),
#   ("LargeDependenceHighGrayLevelEmphasis" (1; #8), 7.734163402727017),
#   ("DependenceNonUniformityNormalized" (1; #2), 0.6135016881535293),
#   ("SmallDependenceEmphasis" (1; #11), 0.3688947865693893),
#   ("GrayLevelVariance" (1; #5), 0.10835123160374235),
#   ("GrayLevelNonUniformity" (1; #4), 0.03267658727587935),
#   ("LargeDependenceLowGrayLevelEmphasis" (1; #9), 0.01385617854804121),
#   ("LargeDependenceEmphasis" (1; #7), 0.0017893117702664357),
#   ("DependenceNonUniformity" (1; #1), 5.551115116476553e-17)],
#  'NUM_AS_ROOT': [("SmallDependenceHighGrayLevelEmphasis" (1; #12), 11.0)],
#  'NUM_NODES': [("HighGrayLevelEmphasis" (1; #6), 27.0),
#   ("LowGrayLevelEmphasis" (1; #10), 23.0),
#   ("DependenceEntropy" (1; #0), 16.0),
#   ("LargeDependenceHighGrayLevelEmphasis" (1; #8), 16.0),
#   ("SmallDependenceHighGrayLevelEmphasis" (1; #12), 16.0),
#   ("SmallDependenceEmphasis" (1; #11), 9.0),
#   ("GrayLevelVariance" (1; #5), 7.0),
#   ("SmallDependenceLowGrayLevelEmphasis" (1; #13), 6.0),
#   ("DependenceNonUniformityNormalized" (1; #2), 3.0),
#   ("LargeDependenceEmphasis" (1; #7), 3.0),
#   ("GrayLevelNonUniformity" (1; #4), 2.0),
#   ("LargeDependenceLowGrayLevelEmphasis" (1; #9), 2.0),
#   ("DependenceNonUniformity" (1; #1), 1.0)]}

# %%
# Model self evaluation
model.make_inspector().evaluation()
# Out:
# Evaluation(num_examples=None, accuracy=0.7784512042999268, loss=1.086113691329956, rmse=None, ndcg=None, aucs=None, auuc=None, qini=None)

# %%
logs = model.make_inspector().training_logs()

plt.figure(figsize=(12, 4))
plt.subplot(1, 2, 1)
plt.plot([log.num_trees for log in logs], [log.evaluation.accuracy for log in logs])
plt.xlabel("Number of trees")
plt.ylabel("Accuracy (out-of-bag)")
plt.subplot(1, 2, 2)
plt.plot([log.num_trees for log in logs], [log.evaluation.loss for log in logs])
plt.xlabel("Number of trees")
plt.ylabel("Logloss (out-of-bag)")
plt.show()

# %% [markdown]
# Calculate the score of our hold-out validation dataset

# %%
predictions = model.predict(val_ds)
y_true      = validation_data["label"]

from sklearn.metrics import roc_auc_score
ROC_AUC = roc_auc_score(y_true, predictions)
print("The ROC AUC score is %.5f" % ROC_AUC )
# Out:
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 64ms/step
# The ROC AUC score is 1.00000

# %%
# Compute binary classification metrics with sklearn
import numpy as np
from sklearn.metrics import (
    accuracy_score,
    precision_score,
    recall_score,
    f1_score,
    roc_auc_score,
    average_precision_score,
    confusion_matrix,
    classification_report,
    matthews_corrcoef,
    log_loss,
    brier_score_loss,
)

# Get predictions (probabilities or class labels)
preds = model.predict(test_ds)
# If model outputs probabilities, convert to labels by threshold 0.5
if preds.ndim == 2:
    # For TFDF classification, preds may be class probabilities with shape (N, 2)
    if preds.shape[1] == 2:
        pos_probs = preds[:, 1]
    else:
        # If single-probability column (positive class)
        pos_probs = preds[:, -1]
    y_pred = (pos_probs >= 0.5).astype(int)
else:
    # Already class labels
    y_pred = preds.astype(int)
    pos_probs = None

# Ground truth labels (must be 0/1 integers)
y_true = test_data["label"].astype(int).to_numpy()

# Core metrics
metrics = {}
metrics["accuracy"] = accuracy_score(y_true, y_pred)
metrics["precision"] = precision_score(y_true, y_pred, zero_division=0)
metrics["recall"] = recall_score(y_true, y_pred, zero_division=0)
metrics["f1"] = f1_score(y_true, y_pred, zero_division=0)
metrics["mcc"] = matthews_corrcoef(y_true, y_pred)

# Probabilistic metrics (only if we have probabilities)
if pos_probs is not None:
    metrics["roc_auc"] = roc_auc_score(y_true, pos_probs)
    metrics["pr_auc"] = average_precision_score(y_true, pos_probs)
    metrics["log_loss"] = log_loss(y_true, pos_probs, labels=[0,1])
    metrics["brier_score"] = brier_score_loss(y_true, pos_probs)

# Confusion matrix and detailed report
cm = confusion_matrix(y_true, y_pred, labels=[0,1])
report = classification_report(y_true, y_pred, digits=4)

print("Sklearn binary metrics:")
for k, v in metrics.items():
    print(f"{k}: {v:.4f}")
print("\nConfusion matrix:\n", cm)
print("\nClassification report:\n", report)
# Out:
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 57ms/step
# Sklearn binary metrics:
# accuracy: 0.9918
# precision: 0.8667
# recall: 1.0000
# f1: 0.9286
# mcc: 0.9269
# roc_auc: 0.9968
# pr_auc: 0.9208
# log_loss: 0.1925
# brier_score: 0.0328
#
# Confusion matrix:
#  [[229   2]
#  [  0  13]]
#
# Classification report:
#                precision    recall  f1-score   support
#
#            0     1.0000    0.9913    0.9957       231
#            1     0.8667    1.0000    0.9286        13
#
#     accuracy                         0.9918       244
#    macro avg     0.9333    0.9957    0.9621       244
# weighted avg     0.9929    0.9918    0.9921       244
