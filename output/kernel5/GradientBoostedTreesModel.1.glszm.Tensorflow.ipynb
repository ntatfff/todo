# %%
# Import packages and modules
import numpy  as np
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow_decision_forests as tfdf

from sklearn.model_selection import train_test_split
# Out:
# 2026-08-15 05:04:09.401416: I tensorflow/core/util/port.cc:113] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2026-08-15 05:04:09.762243: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2026-08-15 05:04:14.611849: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
# Check the version of TensorFlow Decision Forests
print("Found TensorFlow Decision Forests v" + tfdf.__version__)
# Out:
# Found TensorFlow Decision Forests v1.9.1

# %%
datasetPath = 'dataset/firstorder/kernel5/dataset.csv'

# %%
# Parameters
datasetPath = "dataset/glszm/kernel5/1.dataset.csv"

# %%
# train/validation/test = 70/10/20
dataset = pd.read_csv(datasetPath)

train_data, temp_data = train_test_split(dataset, test_size=0.3, random_state=42)
validation_data, test_data = train_test_split(temp_data, test_size=2/3, random_state=42)

# %%
from sklearn.utils.class_weight import compute_class_weight

# tinh class weight tren tap train
classes = np.array([0, 1])
weights = compute_class_weight(class_weight="balanced", classes=classes, y=train_data["label"])
class_weight = {0: weights[0], 1: weights[1]}

# gan sample_weight cho tung dong
train_data["sample_weight"] = train_data["label"].map(class_weight)
validation_data["sample_weight"] = validation_data["label"].map(class_weight)
test_data["sample_weight"] = test_data["label"].map(class_weight)

# Convert the dataset into a TensorFlow dataset.
train_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    train_data, label="label", weight="sample_weight"
)         
val_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    validation_data, label="label", weight="sample_weight"
)
test_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    test_data, label="label", weight="sample_weight"
)
# Out:
# 2026-08-15 05:04:28.278288: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:984] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2026-08-15 05:04:28.279779: W tensorflow/core/common_runtime/gpu/gpu_device.cc:2251] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...

# %%
import keras

# %%
# %%time

# Train a Gradient Boosted Trees model.
model = tfdf.keras.GradientBoostedTreesModel()

# Add evaluation metrics
model.compile(
    metrics=["accuracy"]
)
model.fit(x=train_ds)

# # Train a Gradient Boosted Trees model.
# model = tfdf.keras.GradientBoostedTreesModel(num_trees=1500)
# model.fit(train_ds)
# Out:
# Use /tmp/tmpfe8bsvua as temporary training directory
# Reading training dataset...
# [WARNING 26-08-15 05:04:28.4293 UTC gradient_boosted_trees.cc:1840] "goss_alpha" set but "sampling_method" not equal to "GOSS".
# [WARNING 26-08-15 05:04:28.4296 UTC gradient_boosted_trees.cc:1851] "goss_beta" set but "sampling_method" not equal to "GOSS".
# [WARNING 26-08-15 05:04:28.4296 UTC gradient_boosted_trees.cc:1865] "selective_gradient_boosting_ratio" set but "sampling_method" not equal to "SELGB".
# Training dataset read in 0:00:02.652883. Found 849 examples.
# Training model...
# Model trained in 0:00:00.199904
# Compiling model...
# [INFO 26-08-15 05:04:31.3124 UTC kernel.cc:1233] Loading model from path /tmp/tmpfe8bsvua/model/ with prefix fe261de9d144442c
# [INFO 26-08-15 05:04:31.3141 UTC quick_scorer_extended.cc:911] The binary was compiled without AVX2 support, but your CPU supports it. Enable it for faster model inference.
# [INFO 26-08-15 05:04:31.3141 UTC abstract_model.cc:1362] Engine "GradientBoostedTreesQuickScorerExtended" built
# [INFO 26-08-15 05:04:31.3141 UTC kernel.cc:1061] Use fast generic engine
# Model compiled.
# CPU times: user 5.71 s, sys: 363 ms, total: 6.07 s
# Wall time: 6.17 s

# %%
# Evaluate the model
evaluate = model.evaluate(val_ds, return_dict=True)
print()

for name, value in evaluate.items():
    print(f"{name}: {value:.4f}")
# Out:
# WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 1/1 [==============================] - ETA: 0s - loss: 0.0000e+00 - accuracy: 0.9835
# 1/1 [==============================] - 3s 3s/step - loss: 0.0000e+00 - accuracy: 0.9835
# loss: 0.0000
# accuracy: 0.9835

# %%
# Model Summary
model.summary()
# Out:
# Model: "gradient_boosted_trees_model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
# =================================================================
# Total params: 1 (1.00 Byte)
# Trainable params: 0 (0.00 Byte)
# Non-trainable params: 1 (1.00 Byte)
# _________________________________________________________________
# Type: "GRADIENT_BOOSTED_TREES"
# Task: CLASSIFICATION
# Label: "__LABEL"
#
# Input Features (16):
# 	GrayLevelNonUniformity
# 	GrayLevelNonUniformityNormalized
# 	GrayLevelVariance
# 	HighGrayLevelZoneEmphasis
# 	LargeAreaEmphasis
# 	LargeAreaHighGrayLevelEmphasis
# 	LargeAreaLowGrayLevelEmphasis
# 	LowGrayLevelZoneEmphasis
# 	SizeZoneNonUniformity
# 	SizeZoneNonUniformityNormalized
# 	SmallAreaEmphasis
# 	SmallAreaHighGrayLevelEmphasis
# 	SmallAreaLowGrayLevelEmphasis
# 	ZoneEntropy
# 	ZonePercentage
# 	ZoneVariance
#
# Trained with weights
#
# Variable Importance: INV_MEAN_MIN_DEPTH:
#     1.        "HighGrayLevelZoneEmphasis"  0.455455 ################
#     2.   "SmallAreaHighGrayLevelEmphasis"  0.329935 ########
#     3.    "LargeAreaLowGrayLevelEmphasis"  0.245741 ##
#     4.                      "ZoneEntropy"  0.243235 ##
#     5. "GrayLevelNonUniformityNormalized"  0.235804 ##
#     6.         "LowGrayLevelZoneEmphasis"  0.224115 #
#     7.                     "ZoneVariance"  0.222567 #
#     8.           "GrayLevelNonUniformity"  0.214332
#     9.            "SizeZoneNonUniformity"  0.212157
#    10.                "GrayLevelVariance"  0.209926
#    11.  "SizeZoneNonUniformityNormalized"  0.208149
#    12.    "SmallAreaLowGrayLevelEmphasis"  0.207112
#    13.                "LargeAreaEmphasis"  0.205243
#    14.                "SmallAreaEmphasis"  0.205169
#    15.   "LargeAreaHighGrayLevelEmphasis"  0.204358
#    16.                   "ZonePercentage"  0.203749
#
# Variable Importance: NUM_AS_ROOT:
#     1.      "HighGrayLevelZoneEmphasis" 14.000000 ################
#     2. "SmallAreaHighGrayLevelEmphasis" 11.000000
#
# Variable Importance: NUM_NODES:
#     1.                      "ZoneEntropy" 41.000000 ################
#     2.    "LargeAreaLowGrayLevelEmphasis" 36.000000 #############
#     3.        "HighGrayLevelZoneEmphasis" 34.000000 ############
#     4. "GrayLevelNonUniformityNormalized" 30.000000 ###########
#     5.   "SmallAreaHighGrayLevelEmphasis" 20.000000 ######
#     6.           "GrayLevelNonUniformity" 19.000000 ######
#     7.                     "ZoneVariance" 18.000000 #####
#     8.                "GrayLevelVariance" 13.000000 ###
#     9.            "SizeZoneNonUniformity" 11.000000 ##
#    10.    "SmallAreaLowGrayLevelEmphasis" 10.000000 ##
#    11.         "LowGrayLevelZoneEmphasis"  9.000000 #
#    12.  "SizeZoneNonUniformityNormalized"  9.000000 #
#    13.                "LargeAreaEmphasis"  8.000000 #
#    14.   "LargeAreaHighGrayLevelEmphasis"  5.000000
#    15.                "SmallAreaEmphasis"  5.000000
#    16.                   "ZonePercentage"  5.000000
#
# Variable Importance: SUM_SCORE:
#     1.   "SmallAreaHighGrayLevelEmphasis" 777.546254 ################
#     2.        "HighGrayLevelZoneEmphasis" 141.175367 ##
#     3.                      "ZoneEntropy" 40.719318
#     4. "GrayLevelNonUniformityNormalized" 39.173658
#     5.                     "ZoneVariance"  7.511780
#     6.                "LargeAreaEmphasis"  4.352960
#     7.    "LargeAreaLowGrayLevelEmphasis"  3.647233
#     8.  "SizeZoneNonUniformityNormalized"  2.523022
#     9.           "GrayLevelNonUniformity"  2.433501
#    10.    "SmallAreaLowGrayLevelEmphasis"  2.235255
#    11.         "LowGrayLevelZoneEmphasis"  0.902620
#    12.                   "ZonePercentage"  0.632397
#    13.   "LargeAreaHighGrayLevelEmphasis"  0.361102
#    14.            "SizeZoneNonUniformity"  0.352214
#    15.                "GrayLevelVariance"  0.237323
#    16.                "SmallAreaEmphasis"  0.203105
#
#
#
# Loss: BINOMIAL_LOG_LIKELIHOOD
# Validation loss value: 0.167633
# Number of trees per iteration: 1
# Node format: NOT_SET
# Number of trees: 25
# Total number of nodes: 571
#
# Number of nodes by tree:
# Count: 25 Average: 22.84 StdDev: 2.88
# Min: 19 Max: 27 Ignored: 0
# ----------------------------------------------
# [ 19, 20) 6  24.00%  24.00% #########
# [ 20, 21) 0   0.00%  24.00%
# [ 21, 22) 5  20.00%  44.00% #######
# [ 22, 23) 0   0.00%  44.00%
# [ 23, 24) 3  12.00%  56.00% ####
# [ 24, 25) 0   0.00%  56.00%
# [ 25, 26) 7  28.00%  84.00% ##########
# [ 26, 27) 0   0.00%  84.00%
# [ 27, 27] 4  16.00% 100.00% ######
#
# Depth by leafs:
# Count: 298 Average: 3.9698 StdDev: 1.03419
# Min: 2 Max: 5 Ignored: 0
# ----------------------------------------------
# [ 2, 3)  31  10.40%  10.40% ###
# [ 3, 4)  71  23.83%  34.23% ######
# [ 4, 5)  72  24.16%  58.39% ######
# [ 5, 5] 124  41.61% 100.00% ##########
#
# Number of training obs by leaf:
# Count: 298 Average: 65.3523 StdDev: 189.907
# Min: 5 Max: 703 Ignored: 0
# ----------------------------------------------
# [   5,  39) 271  90.94%  90.94% ##########
# [  39,  74)   2   0.67%  91.61%
# [  74, 109)   0   0.00%  91.61%
# [ 109, 144)   0   0.00%  91.61%
# [ 144, 179)   0   0.00%  91.61%
# [ 179, 214)   0   0.00%  91.61%
# [ 214, 249)   0   0.00%  91.61%
# [ 249, 284)   0   0.00%  91.61%
# [ 284, 319)   0   0.00%  91.61%
# [ 319, 354)   0   0.00%  91.61%
# [ 354, 389)   0   0.00%  91.61%
# [ 389, 424)   0   0.00%  91.61%
# [ 424, 459)   0   0.00%  91.61%
# [ 459, 494)   0   0.00%  91.61%
# [ 494, 529)   0   0.00%  91.61%
# [ 529, 564)   0   0.00%  91.61%
# [ 564, 599)   0   0.00%  91.61%
# [ 599, 634)   0   0.00%  91.61%
# [ 634, 669)   2   0.67%  92.28%
# [ 669, 703]  23   7.72% 100.00% #
#
# Attribute in nodes:
# 	41 : ZoneEntropy [NUMERICAL]
# 	36 : LargeAreaLowGrayLevelEmphasis [NUMERICAL]
# 	34 : HighGrayLevelZoneEmphasis [NUMERICAL]
# 	30 : GrayLevelNonUniformityNormalized [NUMERICAL]
# 	20 : SmallAreaHighGrayLevelEmphasis [NUMERICAL]
# 	19 : GrayLevelNonUniformity [NUMERICAL]
# 	18 : ZoneVariance [NUMERICAL]
# 	13 : GrayLevelVariance [NUMERICAL]
# 	11 : SizeZoneNonUniformity [NUMERICAL]
# 	10 : SmallAreaLowGrayLevelEmphasis [NUMERICAL]
# 	9 : SizeZoneNonUniformityNormalized [NUMERICAL]
# 	9 : LowGrayLevelZoneEmphasis [NUMERICAL]
# 	8 : LargeAreaEmphasis [NUMERICAL]
# 	5 : ZonePercentage [NUMERICAL]
# 	5 : SmallAreaEmphasis [NUMERICAL]
# 	5 : LargeAreaHighGrayLevelEmphasis [NUMERICAL]
#
# Attribute in nodes with depth <= 0:
# 	14 : HighGrayLevelZoneEmphasis [NUMERICAL]
# 	11 : SmallAreaHighGrayLevelEmphasis [NUMERICAL]
#
# Attribute in nodes with depth <= 1:
# 	22 : HighGrayLevelZoneEmphasis [NUMERICAL]
# 	11 : ZoneEntropy [NUMERICAL]
# 	11 : SmallAreaHighGrayLevelEmphasis [NUMERICAL]
# 	9 : LargeAreaLowGrayLevelEmphasis [NUMERICAL]
# 	8 : LowGrayLevelZoneEmphasis [NUMERICAL]
# 	8 : GrayLevelNonUniformityNormalized [NUMERICAL]
# 	6 : ZoneVariance [NUMERICAL]
#
# Attribute in nodes with depth <= 2:
# 	33 : HighGrayLevelZoneEmphasis [NUMERICAL]
# 	19 : ZoneEntropy [NUMERICAL]
# 	18 : GrayLevelNonUniformityNormalized [NUMERICAL]
# 	17 : SmallAreaHighGrayLevelEmphasis [NUMERICAL]
# 	11 : ZoneVariance [NUMERICAL]
# 	10 : LargeAreaLowGrayLevelEmphasis [NUMERICAL]
# 	8 : LowGrayLevelZoneEmphasis [NUMERICAL]
# 	7 : GrayLevelNonUniformity [NUMERICAL]
# 	5 : SizeZoneNonUniformityNormalized [NUMERICAL]
# 	5 : LargeAreaEmphasis [NUMERICAL]
# 	4 : SizeZoneNonUniformity [NUMERICAL]
# 	2 : ZonePercentage [NUMERICAL]
# 	2 : GrayLevelVariance [NUMERICAL]
# 	1 : SmallAreaLowGrayLevelEmphasis [NUMERICAL]
# 	1 : SmallAreaEmphasis [NUMERICAL]
# 	1 : LargeAreaHighGrayLevelEmphasis [NUMERICAL]
#
# Attribute in nodes with depth <= 3:
# 	35 : ZoneEntropy [NUMERICAL]
# 	33 : HighGrayLevelZoneEmphasis [NUMERICAL]
# 	27 : LargeAreaLowGrayLevelEmphasis [NUMERICAL]
# 	24 : GrayLevelNonUniformityNormalized [NUMERICAL]
# 	18 : SmallAreaHighGrayLevelEmphasis [NUMERICAL]
# 	14 : ZoneVariance [NUMERICAL]
# 	11 : GrayLevelNonUniformity [NUMERICAL]
# 	8 : SizeZoneNonUniformity [NUMERICAL]
# 	8 : LowGrayLevelZoneEmphasis [NUMERICAL]
# 	7 : LargeAreaEmphasis [NUMERICAL]
# 	5 : SmallAreaLowGrayLevelEmphasis [NUMERICAL]
# 	5 : SizeZoneNonUniformityNormalized [NUMERICAL]
# 	5 : GrayLevelVariance [NUMERICAL]
# 	4 : ZonePercentage [NUMERICAL]
# 	4 : SmallAreaEmphasis [NUMERICAL]
# 	3 : LargeAreaHighGrayLevelEmphasis [NUMERICAL]
#
# Attribute in nodes with depth <= 5:
# 	41 : ZoneEntropy [NUMERICAL]
# 	36 : LargeAreaLowGrayLevelEmphasis [NUMERICAL]
# 	34 : HighGrayLevelZoneEmphasis [NUMERICAL]
# 	30 : GrayLevelNonUniformityNormalized [NUMERICAL]
# 	20 : SmallAreaHighGrayLevelEmphasis [NUMERICAL]
# 	19 : GrayLevelNonUniformity [NUMERICAL]
# 	18 : ZoneVariance [NUMERICAL]
# 	13 : GrayLevelVariance [NUMERICAL]
# 	11 : SizeZoneNonUniformity [NUMERICAL]
# 	10 : SmallAreaLowGrayLevelEmphasis [NUMERICAL]
# 	9 : SizeZoneNonUniformityNormalized [NUMERICAL]
# 	9 : LowGrayLevelZoneEmphasis [NUMERICAL]
# 	8 : LargeAreaEmphasis [NUMERICAL]
# 	5 : ZonePercentage [NUMERICAL]
# 	5 : SmallAreaEmphasis [NUMERICAL]
# 	5 : LargeAreaHighGrayLevelEmphasis [NUMERICAL]
#
# Condition type in nodes:
# 	273 : HigherCondition
# Condition type in nodes with depth <= 0:
# 	25 : HigherCondition
# Condition type in nodes with depth <= 1:
# 	75 : HigherCondition
# Condition type in nodes with depth <= 2:
# 	144 : HigherCondition
# Condition type in nodes with depth <= 3:
# 	211 : HigherCondition
# Condition type in nodes with depth <= 5:
# 	273 : HigherCondition
#
# Training logs:
# Number of iteration to final model: 25
# 	Iter:1 train-loss:1.203870 valid-loss:1.213367  train-accuracy:0.987733 valid-accuracy:0.984446
# 	Iter:2 train-loss:1.054405 valid-loss:1.072194  train-accuracy:0.989096 valid-accuracy:0.984446
# 	Iter:3 train-loss:0.930051 valid-loss:0.948105  train-accuracy:0.987733 valid-accuracy:0.984446
# 	Iter:4 train-loss:0.824709 valid-loss:0.843750  train-accuracy:0.989096 valid-accuracy:0.984446
# 	Iter:5 train-loss:0.734982 valid-loss:0.753792  train-accuracy:0.987733 valid-accuracy:0.984446
# 	Iter:6 train-loss:0.657704 valid-loss:0.679498  train-accuracy:0.989096 valid-accuracy:0.984446
# 	Iter:16 train-loss:0.242685 valid-loss:0.270933  train-accuracy:0.990459 valid-accuracy:0.992223
# 	Iter:26 train-loss:0.104746 valid-loss:0.171597  train-accuracy:0.995911 valid-accuracy:1.000000
# 	Iter:36 train-loss:0.049884 valid-loss:0.252034  train-accuracy:0.997956 valid-accuracy:0.878317
# 	Iter:46 train-loss:0.024329 valid-loss:0.310923  train-accuracy:0.997956 valid-accuracy:0.878317

# %%
# Model features
model.make_inspector().features()
# Out:
# ["GrayLevelNonUniformity" (1; #0),
#  "GrayLevelNonUniformityNormalized" (1; #1),
#  "GrayLevelVariance" (1; #2),
#  "HighGrayLevelZoneEmphasis" (1; #3),
#  "LargeAreaEmphasis" (1; #4),
#  "LargeAreaHighGrayLevelEmphasis" (1; #5),
#  "LargeAreaLowGrayLevelEmphasis" (1; #6),
#  "LowGrayLevelZoneEmphasis" (1; #7),
#  "SizeZoneNonUniformity" (1; #8),
#  "SizeZoneNonUniformityNormalized" (1; #9),
#  "SmallAreaEmphasis" (1; #10),
#  "SmallAreaHighGrayLevelEmphasis" (1; #11),
#  "SmallAreaLowGrayLevelEmphasis" (1; #12),
#  "ZoneEntropy" (1; #13),
#  "ZonePercentage" (1; #14),
#  "ZoneVariance" (1; #15)]

# %%
# Feature importance
model.make_inspector().variable_importances()
# Out:
# {'INV_MEAN_MIN_DEPTH': [("HighGrayLevelZoneEmphasis" (1; #3),
#    0.45545462652720625),
#   ("SmallAreaHighGrayLevelEmphasis" (1; #11), 0.32993546317313754),
#   ("LargeAreaLowGrayLevelEmphasis" (1; #6), 0.24574057847152142),
#   ("ZoneEntropy" (1; #13), 0.24323521793243746),
#   ("GrayLevelNonUniformityNormalized" (1; #1), 0.23580375787798918),
#   ("LowGrayLevelZoneEmphasis" (1; #7), 0.22411548268564227),
#   ("ZoneVariance" (1; #15), 0.22256667476494124),
#   ("GrayLevelNonUniformity" (1; #0), 0.214331841361035),
#   ("SizeZoneNonUniformity" (1; #8), 0.2121568488370795),
#   ("GrayLevelVariance" (1; #2), 0.2099257185918829),
#   ("SizeZoneNonUniformityNormalized" (1; #9), 0.2081493340815527),
#   ("SmallAreaLowGrayLevelEmphasis" (1; #12), 0.20711178988174422),
#   ("LargeAreaEmphasis" (1; #4), 0.20524343320115648),
#   ("SmallAreaEmphasis" (1; #10), 0.20516939421942917),
#   ("LargeAreaHighGrayLevelEmphasis" (1; #5), 0.2043575591745452),
#   ("ZonePercentage" (1; #14), 0.2037490089032143)],
#  'NUM_AS_ROOT': [("HighGrayLevelZoneEmphasis" (1; #3), 14.0),
#   ("SmallAreaHighGrayLevelEmphasis" (1; #11), 11.0)],
#  'SUM_SCORE': [("SmallAreaHighGrayLevelEmphasis" (1; #11), 777.5462539401083),
#   ("HighGrayLevelZoneEmphasis" (1; #3), 141.17536713998604),
#   ("ZoneEntropy" (1; #13), 40.71931758804559),
#   ("GrayLevelNonUniformityNormalized" (1; #1), 39.17365792121184),
#   ("ZoneVariance" (1; #15), 7.511779742513386),
#   ("LargeAreaEmphasis" (1; #4), 4.352960212792795),
#   ("LargeAreaLowGrayLevelEmphasis" (1; #6), 3.647232600863573),
#   ("SizeZoneNonUniformityNormalized" (1; #9), 2.523021770590318),
#   ("GrayLevelNonUniformity" (1; #0), 2.4335011845473633),
#   ("SmallAreaLowGrayLevelEmphasis" (1; #12), 2.2352548718062892),
#   ("LowGrayLevelZoneEmphasis" (1; #7), 0.9026198933312144),
#   ("ZonePercentage" (1; #14), 0.6323966865648959),
#   ("LargeAreaHighGrayLevelEmphasis" (1; #5), 0.36110243983210377),
#   ("SizeZoneNonUniformity" (1; #8), 0.35221396600425725),
#   ("GrayLevelVariance" (1; #2), 0.23732341963514203),
#   ("SmallAreaEmphasis" (1; #10), 0.20310499214652275)],
#  'NUM_NODES': [("ZoneEntropy" (1; #13), 41.0),
#   ("LargeAreaLowGrayLevelEmphasis" (1; #6), 36.0),
#   ("HighGrayLevelZoneEmphasis" (1; #3), 34.0),
#   ("GrayLevelNonUniformityNormalized" (1; #1), 30.0),
#   ("SmallAreaHighGrayLevelEmphasis" (1; #11), 20.0),
#   ("GrayLevelNonUniformity" (1; #0), 19.0),
#   ("ZoneVariance" (1; #15), 18.0),
#   ("GrayLevelVariance" (1; #2), 13.0),
#   ("SizeZoneNonUniformity" (1; #8), 11.0),
#   ("SmallAreaLowGrayLevelEmphasis" (1; #12), 10.0),
#   ("LowGrayLevelZoneEmphasis" (1; #7), 9.0),
#   ("SizeZoneNonUniformityNormalized" (1; #9), 9.0),
#   ("LargeAreaEmphasis" (1; #4), 8.0),
#   ("LargeAreaHighGrayLevelEmphasis" (1; #5), 5.0),
#   ("SmallAreaEmphasis" (1; #10), 5.0),
#   ("ZonePercentage" (1; #14), 5.0)]}

# %%
# Model self evaluation
model.make_inspector().evaluation()
# Out:
# Evaluation(num_examples=None, accuracy=1.0, loss=0.16763250529766083, rmse=None, ndcg=None, aucs=None, auuc=None, qini=None)

# %%
logs = model.make_inspector().training_logs()

plt.figure(figsize=(12, 4))
plt.subplot(1, 2, 1)
plt.plot([log.num_trees for log in logs], [log.evaluation.accuracy for log in logs])
plt.xlabel("Number of trees")
plt.ylabel("Accuracy (out-of-bag)")
plt.subplot(1, 2, 2)
plt.plot([log.num_trees for log in logs], [log.evaluation.loss for log in logs])
plt.xlabel("Number of trees")
plt.ylabel("Logloss (out-of-bag)")
plt.show()

# %% [markdown]
# Calculate the score of our hold-out validation dataset

# %%
predictions = model.predict(val_ds)
y_true      = validation_data["label"]

from sklearn.metrics import roc_auc_score
ROC_AUC = roc_auc_score(y_true, predictions)
print("The ROC AUC score is %.5f" % ROC_AUC )
# Out:
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 58ms/step
# The ROC AUC score is 1.00000

# %%
# Compute binary classification metrics with sklearn
import numpy as np
from sklearn.metrics import (
    accuracy_score,
    precision_score,
    recall_score,
    f1_score,
    roc_auc_score,
    average_precision_score,
    confusion_matrix,
    classification_report,
    matthews_corrcoef,
    log_loss,
    brier_score_loss,
)

# Get predictions (probabilities or class labels)
preds = model.predict(test_ds)
# If model outputs probabilities, convert to labels by threshold 0.5
if preds.ndim == 2:
    # For TFDF classification, preds may be class probabilities with shape (N, 2)
    if preds.shape[1] == 2:
        pos_probs = preds[:, 1]
    else:
        # If single-probability column (positive class)
        pos_probs = preds[:, -1]
    y_pred = (pos_probs >= 0.5).astype(int)
else:
    # Already class labels
    y_pred = preds.astype(int)
    pos_probs = None

# Ground truth labels (must be 0/1 integers)
y_true = test_data["label"].astype(int).to_numpy()

# Core metrics
metrics = {}
metrics["accuracy"] = accuracy_score(y_true, y_pred)
metrics["precision"] = precision_score(y_true, y_pred, zero_division=0)
metrics["recall"] = recall_score(y_true, y_pred, zero_division=0)
metrics["f1"] = f1_score(y_true, y_pred, zero_division=0)
metrics["mcc"] = matthews_corrcoef(y_true, y_pred)

# Probabilistic metrics (only if we have probabilities)
if pos_probs is not None:
    metrics["roc_auc"] = roc_auc_score(y_true, pos_probs)
    metrics["pr_auc"] = average_precision_score(y_true, pos_probs)
    metrics["log_loss"] = log_loss(y_true, pos_probs, labels=[0,1])
    metrics["brier_score"] = brier_score_loss(y_true, pos_probs)

# Confusion matrix and detailed report
cm = confusion_matrix(y_true, y_pred, labels=[0,1])
report = classification_report(y_true, y_pred, digits=4)

print("Sklearn binary metrics:")
for k, v in metrics.items():
    print(f"{k}: {v:.4f}")
print("\nConfusion matrix:\n", cm)
print("\nClassification report:\n", report)
# Out:
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 71ms/step
# Sklearn binary metrics:
# accuracy: 0.9713
# precision: 0.7619
# recall: 0.8889
# f1: 0.8205
# mcc: 0.8078
# roc_auc: 0.9388
# pr_auc: 0.7794
# log_loss: 0.1106
# brier_score: 0.0245
#
# Confusion matrix:
#  [[221   5]
#  [  2  16]]
#
# Classification report:
#                precision    recall  f1-score   support
#
#            0     0.9910    0.9779    0.9844       226
#            1     0.7619    0.8889    0.8205        18
#
#     accuracy                         0.9713       244
#    macro avg     0.8765    0.9334    0.9025       244
# weighted avg     0.9741    0.9713    0.9723       244
