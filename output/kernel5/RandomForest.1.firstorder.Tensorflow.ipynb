# %%
# Import packages and modules
import numpy  as np
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow_decision_forests as tfdf

from sklearn.model_selection import train_test_split
# Out:
# 2026-08-15 05:16:17.239942: I tensorflow/core/util/port.cc:113] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2026-08-15 05:16:17.604623: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2026-08-15 05:16:22.390444: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
# Check the version of TensorFlow Decision Forests
print("Found TensorFlow Decision Forests v" + tfdf.__version__)
# Out:
# Found TensorFlow Decision Forests v1.9.1

# %%
datasetPath = 'dataset/firstorder/kernel5/dataset.csv'

# %%
# Parameters
datasetPath = "dataset/firstorder/kernel5/1.dataset.csv"

# %%
# train/validation/test = 70/10/20
dataset = pd.read_csv(datasetPath)

train_data, temp_data = train_test_split(dataset, test_size=0.3, random_state=42)
validation_data, test_data = train_test_split(temp_data, test_size=2/3, random_state=42)

# %%
from sklearn.utils.class_weight import compute_class_weight

# tinh class weight tren tap train
classes = np.array([0, 1])
weights = compute_class_weight(class_weight="balanced", classes=classes, y=train_data["label"])
class_weight = {0: weights[0], 1: weights[1]}

# gan sample_weight cho tung dong
train_data["sample_weight"] = train_data["label"].map(class_weight)
validation_data["sample_weight"] = validation_data["label"].map(class_weight)
test_data["sample_weight"] = test_data["label"].map(class_weight)

# Convert the dataset into a TensorFlow dataset.
train_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    train_data, label="label", weight="sample_weight"
)         
val_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    validation_data, label="label", weight="sample_weight"
)
test_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    test_data, label="label", weight="sample_weight"
)
# Out:
# 2026-08-15 05:16:36.159006: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:984] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2026-08-15 05:16:36.161808: W tensorflow/core/common_runtime/gpu/gpu_device.cc:2251] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...

# %%
import keras

# %%
# %%time

# Train a Random Forest model.
model = tfdf.keras.RandomForestModel()

# Add evaluation metrics
model.compile(
    metrics=["accuracy"]
)
model.fit(x=train_ds)

# # Train a Gradient Boosted Trees model.
# model = tfdf.keras.GradientBoostedTreesModel(num_trees=1500)
# model.fit(train_ds)
# Out:
# Use /tmp/tmpj_dxbt4_ as temporary training directory
# Reading training dataset...
# Training dataset read in 0:00:02.624956. Found 849 examples.
# Training model...
# Model trained in 0:00:00.046757
# Compiling model...
# [INFO 26-08-15 05:16:39.0101 UTC kernel.cc:1233] Loading model from path /tmp/tmpj_dxbt4_/model/ with prefix f50a517524434f8f
# [INFO 26-08-15 05:16:39.0151 UTC decision_forest.cc:734] Model loaded with 300 root(s), 3890 node(s), and 18 input feature(s).
# [INFO 26-08-15 05:16:39.0151 UTC abstract_model.cc:1362] Engine "RandomForestOptPred" built
# [INFO 26-08-15 05:16:39.0152 UTC kernel.cc:1061] Use fast generic engine
# Model compiled.
# CPU times: user 5.48 s, sys: 101 ms, total: 5.58 s
# Wall time: 5.86 s

# %%
# Evaluate the model
evaluate = model.evaluate(val_ds, return_dict=True)
print()

for name, value in evaluate.items():
    print(f"{name}: {value:.4f}")
# Out:
# WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 1/1 [==============================] - ETA: 0s - loss: 0.0000e+00 - accuracy: 0.9752
# 1/1 [==============================] - 3s 3s/step - loss: 0.0000e+00 - accuracy: 0.9752
# loss: 0.0000
# accuracy: 0.9752

# %%
# Model Summary
model.summary()
# Out:
# Model: "random_forest_model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
# =================================================================
# Total params: 1 (1.00 Byte)
# Trainable params: 0 (0.00 Byte)
# Non-trainable params: 1 (1.00 Byte)
# _________________________________________________________________
# Type: "RANDOM_FOREST"
# Task: CLASSIFICATION
# Label: "__LABEL"
#
# Input Features (18):
# 	10Percentile
# 	90Percentile
# 	Energy
# 	Entropy
# 	InterquartileRange
# 	Kurtosis
# 	Maximum
# 	Mean
# 	MeanAbsoluteDeviation
# 	Median
# 	Minimum
# 	Range
# 	RobustMeanAbsoluteDeviation
# 	RootMeanSquared
# 	Skewness
# 	TotalEnergy
# 	Uniformity
# 	Variance
#
# Trained with weights
#
# Variable Importance: INV_MEAN_MIN_DEPTH:
#     1.                "90Percentile"  0.350453 ################
#     2.                     "Maximum"  0.296364 ########
#     3.             "RootMeanSquared"  0.281310 #######
#     4.                      "Energy"  0.271337 #####
#     5.                 "TotalEnergy"  0.269657 #####
#     6.                      "Median"  0.257552 ###
#     7.                        "Mean"  0.253628 ###
#     8.                "10Percentile"  0.243968 ##
#     9.                    "Skewness"  0.241569 #
#    10.                    "Kurtosis"  0.234425
#    11.       "MeanAbsoluteDeviation"  0.233594
#    12.                     "Entropy"  0.233155
#    13.          "InterquartileRange"  0.232984
#    14.                     "Minimum"  0.231533
#    15.                  "Uniformity"  0.231510
#    16. "RobustMeanAbsoluteDeviation"  0.230539
#    17.                    "Variance"  0.228755
#    18.                       "Range"  0.227357
#
# Variable Importance: NUM_AS_ROOT:
#     1.    "90Percentile" 94.000000 ################
#     2.         "Maximum" 62.000000 ##########
#     3. "RootMeanSquared" 44.000000 #######
#     4.          "Energy" 35.000000 #####
#     5.     "TotalEnergy" 25.000000 ####
#     6.            "Mean" 20.000000 ###
#     7.          "Median"  8.000000 #
#     8.         "Entropy"  6.000000
#     9.    "10Percentile"  4.000000
#    10.         "Minimum"  1.000000
#    11.      "Uniformity"  1.000000
#
# Variable Importance: NUM_NODES:
#     1.                "90Percentile" 221.000000 ################
#     2.                     "Maximum" 162.000000 ##########
#     3.                      "Median" 146.000000 #########
#     4.             "RootMeanSquared" 143.000000 ########
#     5.                 "TotalEnergy" 133.000000 ########
#     6.                      "Energy" 126.000000 #######
#     7.                        "Mean" 109.000000 #####
#     8.                "10Percentile" 99.000000 ####
#     9.                    "Skewness" 96.000000 ####
#    10.                    "Kurtosis" 92.000000 ####
#    11.                  "Uniformity" 79.000000 ###
#    12.                     "Entropy" 67.000000 ##
#    13.          "InterquartileRange" 66.000000 #
#    14.       "MeanAbsoluteDeviation" 62.000000 #
#    15. "RobustMeanAbsoluteDeviation" 55.000000
#    16.                     "Minimum" 50.000000
#    17.                       "Range" 45.000000
#    18.                    "Variance" 44.000000
#
# Variable Importance: SUM_SCORE:
#     1.                "90Percentile" 56899.791375 ################
#     2.                     "Maximum" 35139.371854 #########
#     3.             "RootMeanSquared" 21930.632202 ######
#     4.                      "Energy" 18787.123365 #####
#     5.                 "TotalEnergy" 14103.195121 ###
#     6.                        "Mean" 10211.728457 ##
#     7.                      "Median" 4417.229515 #
#     8.                     "Entropy" 2408.988168
#     9.                "10Percentile" 1891.771589
#    10.                  "Uniformity" 1246.603424
#    11.       "MeanAbsoluteDeviation" 754.124214
#    12.          "InterquartileRange" 717.328740
#    13. "RobustMeanAbsoluteDeviation" 706.134138
#    14.                    "Kurtosis" 656.882837
#    15.                    "Skewness" 654.586139
#    16.                     "Minimum" 590.941676
#    17.                       "Range" 382.298212
#    18.                    "Variance" 287.144846
#
#
#
# Winner takes all: true
# Out-of-bag evaluation: accuracy:0.964949 logloss:0.09404
# Number of trees: 300
# Total number of nodes: 3890
#
# Number of nodes by tree:
# Count: 300 Average: 12.9667 StdDev: 2.31205
# Min: 7 Max: 23 Ignored: 0
# ----------------------------------------------
# [  7,  8)   3   1.00%   1.00%
# [  8,  9)   0   0.00%   1.00%
# [  9, 10)  18   6.00%   7.00% ##
# [ 10, 11)   0   0.00%   7.00%
# [ 11, 12)  84  28.00%  35.00% ########
# [ 12, 13)   0   0.00%  35.00%
# [ 13, 14) 106  35.33%  70.33% ##########
# [ 14, 15)   0   0.00%  70.33%
# [ 15, 16)  63  21.00%  91.33% ######
# [ 16, 17)   0   0.00%  91.33%
# [ 17, 18)  19   6.33%  97.67% ##
# [ 18, 19)   0   0.00%  97.67%
# [ 19, 20)   6   2.00%  99.67% #
# [ 20, 21)   0   0.00%  99.67%
# [ 21, 22)   0   0.00%  99.67%
# [ 22, 23)   0   0.00%  99.67%
# [ 23, 23]   1   0.33% 100.00%
#
# Depth by leafs:
# Count: 2095 Average: 3.53652 StdDev: 1.50274
# Min: 1 Max: 8 Ignored: 0
# ----------------------------------------------
# [ 1, 2) 239  11.41%  11.41% ####
# [ 2, 3) 317  15.13%  26.54% ######
# [ 3, 4) 419  20.00%  46.54% ########
# [ 4, 5) 545  26.01%  72.55% ##########
# [ 5, 6) 391  18.66%  91.22% #######
# [ 6, 7) 152   7.26%  98.47% ###
# [ 7, 8)  24   1.15%  99.62%
# [ 8, 8]   8   0.38% 100.00%
#
# Number of training obs by leaf:
# Count: 2095 Average: 121.575 StdDev: 258.61
# Min: 5 Max: 803 Ignored: 0
# ----------------------------------------------
# [   5,  44) 1652  78.85%  78.85% ##########
# [  44,  84)  129   6.16%  85.01% #
# [  84, 124)    4   0.19%  85.20%
# [ 124, 164)    8   0.38%  85.58%
# [ 164, 204)    0   0.00%  85.58%
# [ 204, 244)    0   0.00%  85.58%
# [ 244, 284)    2   0.10%  85.68%
# [ 284, 324)    0   0.00%  85.68%
# [ 324, 364)    0   0.00%  85.68%
# [ 364, 404)    0   0.00%  85.68%
# [ 404, 444)    0   0.00%  85.68%
# [ 444, 484)    2   0.10%  85.78%
# [ 484, 524)    0   0.00%  85.78%
# [ 524, 564)    0   0.00%  85.78%
# [ 564, 604)    0   0.00%  85.78%
# [ 604, 644)    6   0.29%  86.06%
# [ 644, 684)    4   0.19%  86.25%
# [ 684, 724)   46   2.20%  88.45%
# [ 724, 764)   86   4.11%  92.55% #
# [ 764, 803]  156   7.45% 100.00% #
#
# Attribute in nodes:
# 	221 : 90Percentile [NUMERICAL]
# 	162 : Maximum [NUMERICAL]
# 	146 : Median [NUMERICAL]
# 	143 : RootMeanSquared [NUMERICAL]
# 	133 : TotalEnergy [NUMERICAL]
# 	126 : Energy [NUMERICAL]
# 	109 : Mean [NUMERICAL]
# 	99 : 10Percentile [NUMERICAL]
# 	96 : Skewness [NUMERICAL]
# 	92 : Kurtosis [NUMERICAL]
# 	79 : Uniformity [NUMERICAL]
# 	67 : Entropy [NUMERICAL]
# 	66 : InterquartileRange [NUMERICAL]
# 	62 : MeanAbsoluteDeviation [NUMERICAL]
# 	55 : RobustMeanAbsoluteDeviation [NUMERICAL]
# 	50 : Minimum [NUMERICAL]
# 	45 : Range [NUMERICAL]
# 	44 : Variance [NUMERICAL]
#
# Attribute in nodes with depth <= 0:
# 	94 : 90Percentile [NUMERICAL]
# 	62 : Maximum [NUMERICAL]
# 	44 : RootMeanSquared [NUMERICAL]
# 	35 : Energy [NUMERICAL]
# 	25 : TotalEnergy [NUMERICAL]
# 	20 : Mean [NUMERICAL]
# 	8 : Median [NUMERICAL]
# 	6 : Entropy [NUMERICAL]
# 	4 : 10Percentile [NUMERICAL]
# 	1 : Uniformity [NUMERICAL]
# 	1 : Minimum [NUMERICAL]
#
# Attribute in nodes with depth <= 1:
# 	161 : 90Percentile [NUMERICAL]
# 	95 : Maximum [NUMERICAL]
# 	84 : RootMeanSquared [NUMERICAL]
# 	78 : Energy [NUMERICAL]
# 	70 : TotalEnergy [NUMERICAL]
# 	40 : Median [NUMERICAL]
# 	40 : Mean [NUMERICAL]
# 	19 : 10Percentile [NUMERICAL]
# 	14 : Entropy [NUMERICAL]
# 	11 : Uniformity [NUMERICAL]
# 	11 : MeanAbsoluteDeviation [NUMERICAL]
# 	8 : Minimum [NUMERICAL]
# 	7 : InterquartileRange [NUMERICAL]
# 	5 : Variance [NUMERICAL]
# 	5 : Skewness [NUMERICAL]
# 	5 : RobustMeanAbsoluteDeviation [NUMERICAL]
# 	4 : Range [NUMERICAL]
# 	4 : Kurtosis [NUMERICAL]
#
# Attribute in nodes with depth <= 2:
# 	179 : 90Percentile [NUMERICAL]
# 	114 : Maximum [NUMERICAL]
# 	110 : RootMeanSquared [NUMERICAL]
# 	101 : TotalEnergy [NUMERICAL]
# 	101 : Energy [NUMERICAL]
# 	98 : Median [NUMERICAL]
# 	74 : Mean [NUMERICAL]
# 	50 : 10Percentile [NUMERICAL]
# 	42 : Skewness [NUMERICAL]
# 	30 : Uniformity [NUMERICAL]
# 	28 : Kurtosis [NUMERICAL]
# 	26 : MeanAbsoluteDeviation [NUMERICAL]
# 	26 : Entropy [NUMERICAL]
# 	23 : RobustMeanAbsoluteDeviation [NUMERICAL]
# 	23 : InterquartileRange [NUMERICAL]
# 	17 : Minimum [NUMERICAL]
# 	15 : Variance [NUMERICAL]
# 	9 : Range [NUMERICAL]
#
# Attribute in nodes with depth <= 3:
# 	204 : 90Percentile [NUMERICAL]
# 	133 : Maximum [NUMERICAL]
# 	126 : RootMeanSquared [NUMERICAL]
# 	122 : Median [NUMERICAL]
# 	119 : TotalEnergy [NUMERICAL]
# 	111 : Energy [NUMERICAL]
# 	93 : Mean [NUMERICAL]
# 	76 : 10Percentile [NUMERICAL]
# 	70 : Skewness [NUMERICAL]
# 	70 : Kurtosis [NUMERICAL]
# 	58 : Uniformity [NUMERICAL]
# 	53 : Entropy [NUMERICAL]
# 	48 : MeanAbsoluteDeviation [NUMERICAL]
# 	46 : InterquartileRange [NUMERICAL]
# 	42 : RobustMeanAbsoluteDeviation [NUMERICAL]
# 	32 : Variance [NUMERICAL]
# 	32 : Minimum [NUMERICAL]
# 	22 : Range [NUMERICAL]
#
# Attribute in nodes with depth <= 5:
# 	221 : 90Percentile [NUMERICAL]
# 	161 : Maximum [NUMERICAL]
# 	144 : Median [NUMERICAL]
# 	143 : RootMeanSquared [NUMERICAL]
# 	133 : TotalEnergy [NUMERICAL]
# 	125 : Energy [NUMERICAL]
# 	109 : Mean [NUMERICAL]
# 	98 : 10Percentile [NUMERICAL]
# 	96 : Skewness [NUMERICAL]
# 	91 : Kurtosis [NUMERICAL]
# 	78 : Uniformity [NUMERICAL]
# 	67 : Entropy [NUMERICAL]
# 	65 : InterquartileRange [NUMERICAL]
# 	60 : MeanAbsoluteDeviation [NUMERICAL]
# 	55 : RobustMeanAbsoluteDeviation [NUMERICAL]
# 	47 : Minimum [NUMERICAL]
# 	43 : Variance [NUMERICAL]
# 	41 : Range [NUMERICAL]
#
# Condition type in nodes:
# 	1795 : HigherCondition
# Condition type in nodes with depth <= 0:
# 	300 : HigherCondition
# Condition type in nodes with depth <= 1:
# 	661 : HigherCondition
# Condition type in nodes with depth <= 2:
# 	1066 : HigherCondition
# Condition type in nodes with depth <= 3:
# 	1457 : HigherCondition
# Condition type in nodes with depth <= 5:
# 	1777 : HigherCondition
# Node format: NOT_SET
#
# Training OOB:
# 	trees: 1, Out-of-bag evaluation: accuracy:0.962503 logloss:1.35155
# 	trees: 13, Out-of-bag evaluation: accuracy:0.903132 logloss:1.99668
# 	trees: 23, Out-of-bag evaluation: accuracy:0.945341 logloss:0.539116
# 	trees: 33, Out-of-bag evaluation: accuracy:0.944088 logloss:0.135854
# 	trees: 43, Out-of-bag evaluation: accuracy:0.963069 logloss:0.131899
# 	trees: 56, Out-of-bag evaluation: accuracy:0.953265 logloss:0.126778
# 	trees: 66, Out-of-bag evaluation: accuracy:0.953265 logloss:0.126271
# 	trees: 76, Out-of-bag evaluation: accuracy:0.953265 logloss:0.124571
# 	trees: 87, Out-of-bag evaluation: accuracy:0.953892 logloss:0.126182
# 	trees: 97, Out-of-bag evaluation: accuracy:0.963696 logloss:0.10263
# 	trees: 108, Out-of-bag evaluation: accuracy:0.953265 logloss:0.0827886
# 	trees: 118, Out-of-bag evaluation: accuracy:0.953265 logloss:0.0824697
# 	trees: 128, Out-of-bag evaluation: accuracy:0.953265 logloss:0.0836095
# 	trees: 139, Out-of-bag evaluation: accuracy:0.953265 logloss:0.0857129
# 	trees: 149, Out-of-bag evaluation: accuracy:0.953265 logloss:0.085749
# 	trees: 159, Out-of-bag evaluation: accuracy:0.953892 logloss:0.0888885
# 	trees: 169, Out-of-bag evaluation: accuracy:0.954519 logloss:0.0904322
# 	trees: 180, Out-of-bag evaluation: accuracy:0.954519 logloss:0.0898002
# 	trees: 190, Out-of-bag evaluation: accuracy:0.954519 logloss:0.0930433
# 	trees: 200, Out-of-bag evaluation: accuracy:0.964323 logloss:0.094192
# 	trees: 211, Out-of-bag evaluation: accuracy:0.964323 logloss:0.095063
# 	trees: 223, Out-of-bag evaluation: accuracy:0.964323 logloss:0.0934194
# 	trees: 233, Out-of-bag evaluation: accuracy:0.964323 logloss:0.0942418
# 	trees: 244, Out-of-bag evaluation: accuracy:0.964323 logloss:0.0945037
# 	trees: 254, Out-of-bag evaluation: accuracy:0.964323 logloss:0.094737
# 	trees: 264, Out-of-bag evaluation: accuracy:0.964323 logloss:0.0951637
# 	trees: 275, Out-of-bag evaluation: accuracy:0.964323 logloss:0.0942027
# 	trees: 285, Out-of-bag evaluation: accuracy:0.964323 logloss:0.0920327
# 	trees: 296, Out-of-bag evaluation: accuracy:0.964949 logloss:0.0934372
# 	trees: 300, Out-of-bag evaluation: accuracy:0.964949 logloss:0.09404

# %%
# Model features
model.make_inspector().features()
# Out:
# ["10Percentile" (1; #0),
#  "90Percentile" (1; #1),
#  "Energy" (1; #2),
#  "Entropy" (1; #3),
#  "InterquartileRange" (1; #4),
#  "Kurtosis" (1; #5),
#  "Maximum" (1; #6),
#  "Mean" (1; #7),
#  "MeanAbsoluteDeviation" (1; #8),
#  "Median" (1; #9),
#  "Minimum" (1; #10),
#  "Range" (1; #11),
#  "RobustMeanAbsoluteDeviation" (1; #12),
#  "RootMeanSquared" (1; #13),
#  "Skewness" (1; #14),
#  "TotalEnergy" (1; #15),
#  "Uniformity" (1; #16),
#  "Variance" (1; #17)]

# %%
# Feature importance
model.make_inspector().variable_importances()
# Out:
# {'INV_MEAN_MIN_DEPTH': [("90Percentile" (1; #1), 0.35045283048605835),
#   ("Maximum" (1; #6), 0.29636354869476544),
#   ("RootMeanSquared" (1; #13), 0.2813102807744517),
#   ("Energy" (1; #2), 0.2713369157462985),
#   ("TotalEnergy" (1; #15), 0.2696566692764391),
#   ("Median" (1; #9), 0.2575524005007965),
#   ("Mean" (1; #7), 0.2536279532895146),
#   ("10Percentile" (1; #0), 0.2439684764330004),
#   ("Skewness" (1; #14), 0.2415694344367457),
#   ("Kurtosis" (1; #5), 0.23442456521375152),
#   ("MeanAbsoluteDeviation" (1; #8), 0.23359381928057446),
#   ("Entropy" (1; #3), 0.23315530055136935),
#   ("InterquartileRange" (1; #4), 0.23298371394530823),
#   ("Minimum" (1; #10), 0.23153309208156858),
#   ("Uniformity" (1; #16), 0.23150997789630948),
#   ("RobustMeanAbsoluteDeviation" (1; #12), 0.23053911388815218),
#   ("Variance" (1; #17), 0.2287554703875139),
#   ("Range" (1; #11), 0.2273570702936338)],
#  'NUM_AS_ROOT': [("90Percentile" (1; #1), 94.0),
#   ("Maximum" (1; #6), 62.0),
#   ("RootMeanSquared" (1; #13), 44.0),
#   ("Energy" (1; #2), 35.0),
#   ("TotalEnergy" (1; #15), 25.0),
#   ("Mean" (1; #7), 20.0),
#   ("Median" (1; #9), 8.0),
#   ("Entropy" (1; #3), 6.0),
#   ("10Percentile" (1; #0), 4.0),
#   ("Minimum" (1; #10), 1.0),
#   ("Uniformity" (1; #16), 1.0)],
#  'SUM_SCORE': [("90Percentile" (1; #1), 56899.79137526442),
#   ("Maximum" (1; #6), 35139.371853844634),
#   ("RootMeanSquared" (1; #13), 21930.632201751214),
#   ("Energy" (1; #2), 18787.12336477634),
#   ("TotalEnergy" (1; #15), 14103.195121301635),
#   ("Mean" (1; #7), 10211.72845694244),
#   ("Median" (1; #9), 4417.229515333943),
#   ("Entropy" (1; #3), 2408.9881681949696),
#   ("10Percentile" (1; #0), 1891.7715886172678),
#   ("Uniformity" (1; #16), 1246.603423852944),
#   ("MeanAbsoluteDeviation" (1; #8), 754.1242139258618),
#   ("InterquartileRange" (1; #4), 717.3287401342857),
#   ("RobustMeanAbsoluteDeviation" (1; #12), 706.1341379847017),
#   ("Kurtosis" (1; #5), 656.8828368348074),
#   ("Skewness" (1; #14), 654.5861391688726),
#   ("Minimum" (1; #10), 590.9416759047843),
#   ("Range" (1; #11), 382.2982116657335),
#   ("Variance" (1; #17), 287.14484616346806)],
#  'NUM_NODES': [("90Percentile" (1; #1), 221.0),
#   ("Maximum" (1; #6), 162.0),
#   ("Median" (1; #9), 146.0),
#   ("RootMeanSquared" (1; #13), 143.0),
#   ("TotalEnergy" (1; #15), 133.0),
#   ("Energy" (1; #2), 126.0),
#   ("Mean" (1; #7), 109.0),
#   ("10Percentile" (1; #0), 99.0),
#   ("Skewness" (1; #14), 96.0),
#   ("Kurtosis" (1; #5), 92.0),
#   ("Uniformity" (1; #16), 79.0),
#   ("Entropy" (1; #3), 67.0),
#   ("InterquartileRange" (1; #4), 66.0),
#   ("MeanAbsoluteDeviation" (1; #8), 62.0),
#   ("RobustMeanAbsoluteDeviation" (1; #12), 55.0),
#   ("Minimum" (1; #10), 50.0),
#   ("Range" (1; #11), 45.0),
#   ("Variance" (1; #17), 44.0)]}

# %%
# Model self evaluation
model.make_inspector().evaluation()
# Out:
# Evaluation(num_examples=849, accuracy=0.9649491377300062, loss=0.09403997788263156, rmse=None, ndcg=None, aucs=None, auuc=None, qini=None)

# %%
logs = model.make_inspector().training_logs()

plt.figure(figsize=(12, 4))
plt.subplot(1, 2, 1)
plt.plot([log.num_trees for log in logs], [log.evaluation.accuracy for log in logs])
plt.xlabel("Number of trees")
plt.ylabel("Accuracy (out-of-bag)")
plt.subplot(1, 2, 2)
plt.plot([log.num_trees for log in logs], [log.evaluation.loss for log in logs])
plt.xlabel("Number of trees")
plt.ylabel("Logloss (out-of-bag)")
plt.show()

# %% [markdown]
# Calculate the score of our hold-out validation dataset

# %%
predictions = model.predict(val_ds)
y_true      = validation_data["label"]

from sklearn.metrics import roc_auc_score
ROC_AUC = roc_auc_score(y_true, predictions)
print("The ROC AUC score is %.5f" % ROC_AUC )
# Out:
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 62ms/step
# The ROC AUC score is 1.00000

# %%
# Compute binary classification metrics with sklearn
import numpy as np
from sklearn.metrics import (
    accuracy_score,
    precision_score,
    recall_score,
    f1_score,
    roc_auc_score,
    average_precision_score,
    confusion_matrix,
    classification_report,
    matthews_corrcoef,
    log_loss,
    brier_score_loss,
)

# Get predictions (probabilities or class labels)
preds = model.predict(test_ds)
# If model outputs probabilities, convert to labels by threshold 0.5
if preds.ndim == 2:
    # For TFDF classification, preds may be class probabilities with shape (N, 2)
    if preds.shape[1] == 2:
        pos_probs = preds[:, 1]
    else:
        # If single-probability column (positive class)
        pos_probs = preds[:, -1]
    y_pred = (pos_probs >= 0.5).astype(int)
else:
    # Already class labels
    y_pred = preds.astype(int)
    pos_probs = None

# Ground truth labels (must be 0/1 integers)
y_true = test_data["label"].astype(int).to_numpy()

# Core metrics
metrics = {}
metrics["accuracy"] = accuracy_score(y_true, y_pred)
metrics["precision"] = precision_score(y_true, y_pred, zero_division=0)
metrics["recall"] = recall_score(y_true, y_pred, zero_division=0)
metrics["f1"] = f1_score(y_true, y_pred, zero_division=0)
metrics["mcc"] = matthews_corrcoef(y_true, y_pred)

# Probabilistic metrics (only if we have probabilities)
if pos_probs is not None:
    metrics["roc_auc"] = roc_auc_score(y_true, pos_probs)
    metrics["pr_auc"] = average_precision_score(y_true, pos_probs)
    metrics["log_loss"] = log_loss(y_true, pos_probs, labels=[0,1])
    metrics["brier_score"] = brier_score_loss(y_true, pos_probs)

# Confusion matrix and detailed report
cm = confusion_matrix(y_true, y_pred, labels=[0,1])
report = classification_report(y_true, y_pred, digits=4)

print("Sklearn binary metrics:")
for k, v in metrics.items():
    print(f"{k}: {v:.4f}")
print("\nConfusion matrix:\n", cm)
print("\nClassification report:\n", report)
# Out:
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 75ms/step
# Sklearn binary metrics:
# accuracy: 0.9918
# precision: 1.0000
# recall: 0.8667
# f1: 0.9286
# mcc: 0.9269
# roc_auc: 0.9974
# pr_auc: 0.9733
# log_loss: 0.0297
# brier_score: 0.0063
#
# Confusion matrix:
#  [[229   0]
#  [  2  13]]
#
# Classification report:
#                precision    recall  f1-score   support
#
#            0     0.9913    1.0000    0.9957       229
#            1     1.0000    0.8667    0.9286        15
#
#     accuracy                         0.9918       244
#    macro avg     0.9957    0.9333    0.9621       244
# weighted avg     0.9919    0.9918    0.9915       244
