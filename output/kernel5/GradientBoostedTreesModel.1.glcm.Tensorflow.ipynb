# %%
# Import packages and modules
import numpy  as np
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow_decision_forests as tfdf

from sklearn.model_selection import train_test_split
# Out:
# 2026-08-15 05:02:19.375614: I tensorflow/core/util/port.cc:113] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2026-08-15 05:02:19.731803: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2026-08-15 05:02:24.575153: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
# Check the version of TensorFlow Decision Forests
print("Found TensorFlow Decision Forests v" + tfdf.__version__)
# Out:
# Found TensorFlow Decision Forests v1.9.1

# %%
datasetPath = 'dataset/firstorder/kernel5/dataset.csv'

# %%
# Parameters
datasetPath = "dataset/glcm/kernel5/1.dataset.csv"

# %%
# train/validation/test = 70/10/20
dataset = pd.read_csv(datasetPath)

train_data, temp_data = train_test_split(dataset, test_size=0.3, random_state=42)
validation_data, test_data = train_test_split(temp_data, test_size=2/3, random_state=42)

# %%
from sklearn.utils.class_weight import compute_class_weight

# tinh class weight tren tap train
classes = np.array([0, 1])
weights = compute_class_weight(class_weight="balanced", classes=classes, y=train_data["label"])
class_weight = {0: weights[0], 1: weights[1]}

# gan sample_weight cho tung dong
train_data["sample_weight"] = train_data["label"].map(class_weight)
validation_data["sample_weight"] = validation_data["label"].map(class_weight)
test_data["sample_weight"] = test_data["label"].map(class_weight)

# Convert the dataset into a TensorFlow dataset.
train_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    train_data, label="label", weight="sample_weight"
)         
val_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    validation_data, label="label", weight="sample_weight"
)
test_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    test_data, label="label", weight="sample_weight"
)
# Out:
# 2026-08-15 05:02:37.457103: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:984] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2026-08-15 05:02:37.458837: W tensorflow/core/common_runtime/gpu/gpu_device.cc:2251] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...

# %%
import keras

# %%
# %%time

# Train a Gradient Boosted Trees model.
model = tfdf.keras.GradientBoostedTreesModel()

# Add evaluation metrics
model.compile(
    metrics=["accuracy"]
)
model.fit(x=train_ds)

# # Train a Gradient Boosted Trees model.
# model = tfdf.keras.GradientBoostedTreesModel(num_trees=1500)
# model.fit(train_ds)
# Out:
# Use /tmp/tmpu_gf4rpq as temporary training directory
# Reading training dataset...
# [WARNING 26-08-15 05:02:37.6300 UTC gradient_boosted_trees.cc:1840] "goss_alpha" set but "sampling_method" not equal to "GOSS".
# [WARNING 26-08-15 05:02:37.6303 UTC gradient_boosted_trees.cc:1851] "goss_beta" set but "sampling_method" not equal to "GOSS".
# [WARNING 26-08-15 05:02:37.6303 UTC gradient_boosted_trees.cc:1865] "selective_gradient_boosting_ratio" set but "sampling_method" not equal to "SELGB".
# Training dataset read in 0:00:02.702082. Found 849 examples.
# Training model...
# Model trained in 0:00:01.014597
# Compiling model...
# [INFO 26-08-15 05:02:41.3723 UTC kernel.cc:1233] Loading model from path /tmp/tmpu_gf4rpq/model/ with prefix 293dbf397e354785
# [INFO 26-08-15 05:02:41.3788 UTC quick_scorer_extended.cc:911] The binary was compiled without AVX2 support, but your CPU supports it. Enable it for faster model inference.
# [INFO 26-08-15 05:02:41.3793 UTC abstract_model.cc:1362] Engine "GradientBoostedTreesQuickScorerExtended" built
# [INFO 26-08-15 05:02:41.3793 UTC kernel.cc:1061] Use fast generic engine
# Model compiled.
# CPU times: user 6.94 s, sys: 1.35 s, total: 8.29 s
# Wall time: 7.06 s

# %%
# Evaluate the model
evaluate = model.evaluate(val_ds, return_dict=True)
print()

for name, value in evaluate.items():
    print(f"{name}: {value:.4f}")
# Out:
# WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 1/1 [==============================] - ETA: 0s - loss: 0.0000e+00 - accuracy: 0.9835
# 1/1 [==============================] - 4s 4s/step - loss: 0.0000e+00 - accuracy: 0.9835
# loss: 0.0000
# accuracy: 0.9835

# %%
# Model Summary
model.summary()
# Out:
# Model: "gradient_boosted_trees_model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
# =================================================================
# Total params: 1 (1.00 Byte)
# Trainable params: 0 (0.00 Byte)
# Non-trainable params: 1 (1.00 Byte)
# _________________________________________________________________
# Type: "GRADIENT_BOOSTED_TREES"
# Task: CLASSIFICATION
# Label: "__LABEL"
#
# Input Features (24):
# 	Autocorrelation
# 	ClusterProminence
# 	ClusterShade
# 	ClusterTendency
# 	Contrast
# 	Correlation
# 	DifferenceAverage
# 	DifferenceEntropy
# 	DifferenceVariance
# 	Id
# 	Idm
# 	Idmn
# 	Idn
# 	Imc1
# 	Imc2
# 	InverseVariance
# 	JointAverage
# 	JointEnergy
# 	JointEntropy
# 	MCC
# 	MaximumProbability
# 	SumAverage
# 	SumEntropy
# 	SumSquares
#
# Trained with weights
#
# Variable Importance: INV_MEAN_MIN_DEPTH:
#     1.    "Autocorrelation"  0.570342 ################
#     2.         "SumEntropy"  0.265204 ###
#     3.                "Idn"  0.246521 ##
#     4.        "Correlation"  0.219026 #
#     5.        "JointEnergy"  0.210078
#     6.       "ClusterShade"  0.209574
#     7.         "SumAverage"  0.207900
#     8.                "MCC"  0.207818
#     9.       "JointAverage"  0.206440
#    10.               "Imc2"  0.206356
#    11.  "ClusterProminence"  0.203827
#    12.               "Imc1"  0.200094
#    13.       "JointEntropy"  0.198306
#    14. "DifferenceVariance"  0.198116
#    15.                "Idm"  0.198046
#    16.    "ClusterTendency"  0.197773
#    17. "MaximumProbability"  0.197550
#    18.                 "Id"  0.197164
#    19.  "DifferenceEntropy"  0.196998
#    20.    "InverseVariance"  0.196227
#    21.         "SumSquares"  0.195735
#    22.           "Contrast"  0.194935
#    23.               "Idmn"  0.194918
#    24.  "DifferenceAverage"  0.194041
#
# Variable Importance: NUM_AS_ROOT:
#     1. "Autocorrelation" 142.000000 ################
#     2.             "Idn" 33.000000 #
#     3.      "SumEntropy" 25.000000
#
# Variable Importance: NUM_NODES:
#     1.    "Autocorrelation" 495.000000 ################
#     2.         "SumEntropy" 309.000000 #########
#     3.        "Correlation" 192.000000 ######
#     4.       "ClusterShade" 163.000000 #####
#     5.         "SumAverage" 144.000000 ####
#     6.       "JointAverage" 136.000000 ####
#     7.        "JointEnergy" 130.000000 ####
#     8.               "Imc2" 113.000000 ###
#     9.                "MCC" 101.000000 ###
#    10.  "ClusterProminence" 98.000000 ###
#    11.                "Idn" 97.000000 ##
#    12.               "Imc1" 96.000000 ##
#    13.       "JointEntropy" 71.000000 ##
#    14. "MaximumProbability" 65.000000 #
#    15. "DifferenceVariance" 63.000000 #
#    16.                "Idm" 45.000000 #
#    17.                 "Id" 44.000000 #
#    18.  "DifferenceEntropy" 40.000000 #
#    19.    "ClusterTendency" 39.000000 #
#    20.    "InverseVariance" 37.000000 #
#    21.         "SumSquares" 33.000000
#    22.           "Contrast" 32.000000
#    23.               "Idmn" 32.000000
#    24.  "DifferenceAverage"  6.000000
#
# Variable Importance: SUM_SCORE:
#     1.    "Autocorrelation" 844.906045 ################
#     2.        "JointEnergy" 116.445151 ##
#     3.                "MCC" 28.011046
#     4.        "Correlation" 25.626285
#     5.         "SumEntropy" 19.138006
#     6.       "JointAverage"  1.941696
#     7.  "ClusterProminence"  1.655858
#     8.       "ClusterShade"  1.613177
#     9.               "Imc2"  1.584102
#    10. "MaximumProbability"  1.110446
#    11.               "Imc1"  0.889972
#    12.         "SumAverage"  0.870221
#    13.         "SumSquares"  0.596728
#    14.           "Contrast"  0.355297
#    15.                 "Id"  0.338552
#    16. "DifferenceVariance"  0.301693
#    17.       "JointEntropy"  0.263660
#    18.    "InverseVariance"  0.223690
#    19.                "Idm"  0.201664
#    20.                "Idn"  0.050248
#    21.    "ClusterTendency"  0.041966
#    22.               "Idmn"  0.009655
#    23.  "DifferenceEntropy"  0.008554
#    24.  "DifferenceAverage"  0.001072
#
#
#
# Loss: BINOMIAL_LOG_LIKELIHOOD
# Validation loss value: 7.56502e-06
# Number of trees per iteration: 1
# Node format: NOT_SET
# Number of trees: 200
# Total number of nodes: 5362
#
# Number of nodes by tree:
# Count: 200 Average: 26.81 StdDev: 4.51485
# Min: 19 Max: 37 Ignored: 0
# ----------------------------------------------
# [ 19, 20)  6   3.00%   3.00% ##
# [ 20, 21)  0   0.00%   3.00%
# [ 21, 22) 37  18.50%  21.50% ##########
# [ 22, 23)  0   0.00%  21.50%
# [ 23, 24) 18   9.00%  30.50% #####
# [ 24, 25)  0   0.00%  30.50%
# [ 25, 26) 25  12.50%  43.00% #######
# [ 26, 27)  0   0.00%  43.00%
# [ 27, 28) 31  15.50%  58.50% ########
# [ 28, 29)  0   0.00%  58.50%
# [ 29, 30) 31  15.50%  74.00% ########
# [ 30, 31)  0   0.00%  74.00%
# [ 31, 32) 27  13.50%  87.50% #######
# [ 32, 33)  0   0.00%  87.50%
# [ 33, 34) 14   7.00%  94.50% ####
# [ 34, 35)  0   0.00%  94.50%
# [ 35, 36)  5   2.50%  97.00% #
# [ 36, 37)  0   0.00%  97.00%
# [ 37, 37]  6   3.00% 100.00% ##
#
# Depth by leafs:
# Count: 2781 Average: 4.18447 StdDev: 0.987584
# Min: 2 Max: 5 Ignored: 0
# ----------------------------------------------
# [ 2, 3)  204   7.34%   7.34% #
# [ 3, 4)  535  19.24%  26.57% ####
# [ 4, 5)  586  21.07%  47.64% ####
# [ 5, 5] 1456  52.36% 100.00% ##########
#
# Number of training obs by leaf:
# Count: 2781 Average: 56.023 StdDev: 164.959
# Min: 5 Max: 713 Ignored: 0
# ----------------------------------------------
# [   5,  40) 2507  90.15%  90.15% ##########
# [  40,  75)   33   1.19%  91.33%
# [  75, 111)   27   0.97%  92.30%
# [ 111, 146)   10   0.36%  92.66%
# [ 146, 182)    0   0.00%  92.66%
# [ 182, 217)    0   0.00%  92.66%
# [ 217, 253)    2   0.07%  92.74%
# [ 253, 288)    2   0.07%  92.81%
# [ 288, 324)    0   0.00%  92.81%
# [ 324, 359)    0   0.00%  92.81%
# [ 359, 394)    0   0.00%  92.81%
# [ 394, 430)    2   0.07%  92.88%
# [ 430, 465)    2   0.07%  92.95%
# [ 465, 501)    2   0.07%  93.02%
# [ 501, 536)    4   0.14%  93.17%
# [ 536, 572)    7   0.25%  93.42%
# [ 572, 607)   32   1.15%  94.57%
# [ 607, 643)   18   0.65%  95.22%
# [ 643, 678)   73   2.62%  97.84%
# [ 678, 713]   60   2.16% 100.00%
#
# Attribute in nodes:
# 	495 : Autocorrelation [NUMERICAL]
# 	309 : SumEntropy [NUMERICAL]
# 	192 : Correlation [NUMERICAL]
# 	163 : ClusterShade [NUMERICAL]
# 	144 : SumAverage [NUMERICAL]
# 	136 : JointAverage [NUMERICAL]
# 	130 : JointEnergy [NUMERICAL]
# 	113 : Imc2 [NUMERICAL]
# 	101 : MCC [NUMERICAL]
# 	98 : ClusterProminence [NUMERICAL]
# 	97 : Idn [NUMERICAL]
# 	96 : Imc1 [NUMERICAL]
# 	71 : JointEntropy [NUMERICAL]
# 	65 : MaximumProbability [NUMERICAL]
# 	63 : DifferenceVariance [NUMERICAL]
# 	45 : Idm [NUMERICAL]
# 	44 : Id [NUMERICAL]
# 	40 : DifferenceEntropy [NUMERICAL]
# 	39 : ClusterTendency [NUMERICAL]
# 	37 : InverseVariance [NUMERICAL]
# 	33 : SumSquares [NUMERICAL]
# 	32 : Idmn [NUMERICAL]
# 	32 : Contrast [NUMERICAL]
# 	6 : DifferenceAverage [NUMERICAL]
#
# Attribute in nodes with depth <= 0:
# 	142 : Autocorrelation [NUMERICAL]
# 	33 : Idn [NUMERICAL]
# 	25 : SumEntropy [NUMERICAL]
#
# Attribute in nodes with depth <= 1:
# 	185 : Autocorrelation [NUMERICAL]
# 	99 : SumEntropy [NUMERICAL]
# 	77 : Idn [NUMERICAL]
# 	43 : Correlation [NUMERICAL]
# 	39 : JointEnergy [NUMERICAL]
# 	29 : ClusterProminence [NUMERICAL]
# 	21 : ClusterShade [NUMERICAL]
# 	20 : Imc1 [NUMERICAL]
# 	16 : Imc2 [NUMERICAL]
# 	12 : MCC [NUMERICAL]
# 	10 : JointAverage [NUMERICAL]
# 	9 : SumAverage [NUMERICAL]
# 	8 : DifferenceVariance [NUMERICAL]
# 	7 : Id [NUMERICAL]
# 	7 : ClusterTendency [NUMERICAL]
# 	5 : InverseVariance [NUMERICAL]
# 	4 : Idmn [NUMERICAL]
# 	3 : DifferenceEntropy [NUMERICAL]
# 	2 : MaximumProbability [NUMERICAL]
# 	2 : Idm [NUMERICAL]
# 	1 : JointEntropy [NUMERICAL]
# 	1 : Contrast [NUMERICAL]
#
# Attribute in nodes with depth <= 2:
# 	266 : Autocorrelation [NUMERICAL]
# 	196 : SumEntropy [NUMERICAL]
# 	93 : Correlation [NUMERICAL]
# 	82 : Idn [NUMERICAL]
# 	69 : JointEnergy [NUMERICAL]
# 	69 : ClusterShade [NUMERICAL]
# 	49 : Imc1 [NUMERICAL]
# 	43 : MCC [NUMERICAL]
# 	42 : Imc2 [NUMERICAL]
# 	41 : SumAverage [NUMERICAL]
# 	40 : ClusterProminence [NUMERICAL]
# 	34 : JointAverage [NUMERICAL]
# 	27 : MaximumProbability [NUMERICAL]
# 	27 : DifferenceVariance [NUMERICAL]
# 	23 : Idm [NUMERICAL]
# 	19 : JointEntropy [NUMERICAL]
# 	14 : Contrast [NUMERICAL]
# 	13 : ClusterTendency [NUMERICAL]
# 	11 : InverseVariance [NUMERICAL]
# 	10 : Idmn [NUMERICAL]
# 	10 : Id [NUMERICAL]
# 	9 : SumSquares [NUMERICAL]
# 	9 : DifferenceEntropy [NUMERICAL]
#
# Attribute in nodes with depth <= 3:
# 	391 : Autocorrelation [NUMERICAL]
# 	244 : SumEntropy [NUMERICAL]
# 	151 : Correlation [NUMERICAL]
# 	107 : ClusterShade [NUMERICAL]
# 	95 : SumAverage [NUMERICAL]
# 	88 : JointAverage [NUMERICAL]
# 	87 : Idn [NUMERICAL]
# 	86 : JointEnergy [NUMERICAL]
# 	84 : Imc2 [NUMERICAL]
# 	80 : Imc1 [NUMERICAL]
# 	77 : ClusterProminence [NUMERICAL]
# 	72 : MCC [NUMERICAL]
# 	42 : DifferenceVariance [NUMERICAL]
# 	38 : MaximumProbability [NUMERICAL]
# 	38 : JointEntropy [NUMERICAL]
# 	33 : Idm [NUMERICAL]
# 	25 : InverseVariance [NUMERICAL]
# 	23 : Id [NUMERICAL]
# 	22 : Contrast [NUMERICAL]
# 	21 : DifferenceEntropy [NUMERICAL]
# 	17 : SumSquares [NUMERICAL]
# 	16 : Idmn [NUMERICAL]
# 	15 : ClusterTendency [NUMERICAL]
# 	1 : DifferenceAverage [NUMERICAL]
#
# Attribute in nodes with depth <= 5:
# 	495 : Autocorrelation [NUMERICAL]
# 	309 : SumEntropy [NUMERICAL]
# 	192 : Correlation [NUMERICAL]
# 	163 : ClusterShade [NUMERICAL]
# 	144 : SumAverage [NUMERICAL]
# 	136 : JointAverage [NUMERICAL]
# 	130 : JointEnergy [NUMERICAL]
# 	113 : Imc2 [NUMERICAL]
# 	101 : MCC [NUMERICAL]
# 	98 : ClusterProminence [NUMERICAL]
# 	97 : Idn [NUMERICAL]
# 	96 : Imc1 [NUMERICAL]
# 	71 : JointEntropy [NUMERICAL]
# 	65 : MaximumProbability [NUMERICAL]
# 	63 : DifferenceVariance [NUMERICAL]
# 	45 : Idm [NUMERICAL]
# 	44 : Id [NUMERICAL]
# 	40 : DifferenceEntropy [NUMERICAL]
# 	39 : ClusterTendency [NUMERICAL]
# 	37 : InverseVariance [NUMERICAL]
# 	33 : SumSquares [NUMERICAL]
# 	32 : Idmn [NUMERICAL]
# 	32 : Contrast [NUMERICAL]
# 	6 : DifferenceAverage [NUMERICAL]
#
# Condition type in nodes:
# 	2581 : HigherCondition
# Condition type in nodes with depth <= 0:
# 	200 : HigherCondition
# Condition type in nodes with depth <= 1:
# 	600 : HigherCondition
# Condition type in nodes with depth <= 2:
# 	1196 : HigherCondition
# Condition type in nodes with depth <= 3:
# 	1853 : HigherCondition
# Condition type in nodes with depth <= 5:
# 	2581 : HigherCondition
#
# Training logs:
# Number of iteration to final model: 200
# 	Iter:1 train-loss:1.200601 valid-loss:1.200812  train-accuracy:0.993861 valid-accuracy:1.000000
# 	Iter:2 train-loss:1.048409 valid-loss:1.048262  train-accuracy:0.995225 valid-accuracy:1.000000
# 	Iter:3 train-loss:0.921573 valid-loss:0.920881  train-accuracy:0.993861 valid-accuracy:1.000000
# 	Iter:4 train-loss:0.814336 valid-loss:0.813070  train-accuracy:0.995225 valid-accuracy:1.000000
# 	Iter:5 train-loss:0.722825 valid-loss:0.720905  train-accuracy:0.993861 valid-accuracy:1.000000
# 	Iter:6 train-loss:0.643995 valid-loss:0.641441  train-accuracy:0.995225 valid-accuracy:1.000000
# 	Iter:16 train-loss:0.224938 valid-loss:0.217714  train-accuracy:0.996589 valid-accuracy:1.000000
# 	Iter:26 train-loss:0.087764 valid-loss:0.080975  train-accuracy:0.998636 valid-accuracy:1.000000
# 	Iter:36 train-loss:0.037106 valid-loss:0.035471  train-accuracy:0.999318 valid-accuracy:1.000000
# 	Iter:46 train-loss:0.014884 valid-loss:0.014788  train-accuracy:0.999318 valid-accuracy:1.000000
# 	Iter:56 train-loss:0.006400 valid-loss:0.006404  train-accuracy:1.000000 valid-accuracy:1.000000
# 	Iter:66 train-loss:0.002781 valid-loss:0.002881  train-accuracy:1.000000 valid-accuracy:1.000000
# 	Iter:76 train-loss:0.001225 valid-loss:0.001370  train-accuracy:1.000000 valid-accuracy:1.000000
# 	Iter:86 train-loss:0.000511 valid-loss:0.000522  train-accuracy:1.000000 valid-accuracy:1.000000
# 	Iter:96 train-loss:0.000206 valid-loss:0.000201  train-accuracy:1.000000 valid-accuracy:1.000000
# 	Iter:106 train-loss:0.000089 valid-loss:0.000095  train-accuracy:1.000000 valid-accuracy:1.000000
# 	Iter:116 train-loss:0.000039 valid-loss:0.000042  train-accuracy:1.000000 valid-accuracy:1.000000
# 	Iter:126 train-loss:0.000022 valid-loss:0.000024  train-accuracy:1.000000 valid-accuracy:1.000000
# 	Iter:136 train-loss:0.000015 valid-loss:0.000019  train-accuracy:1.000000 valid-accuracy:1.000000
# 	Iter:146 train-loss:0.000012 valid-loss:0.000016  train-accuracy:1.000000 valid-accuracy:1.000000
# 	Iter:156 train-loss:0.000009 valid-loss:0.000013  train-accuracy:1.000000 valid-accuracy:1.000000
# 	Iter:166 train-loss:0.000007 valid-loss:0.000012  train-accuracy:1.000000 valid-accuracy:1.000000
# 	Iter:176 train-loss:0.000006 valid-loss:0.000010  train-accuracy:1.000000 valid-accuracy:1.000000
# 	Iter:186 train-loss:0.000005 valid-loss:0.000009  train-accuracy:1.000000 valid-accuracy:1.000000
# 	Iter:196 train-loss:0.000005 valid-loss:0.000008  train-accuracy:1.000000 valid-accuracy:1.000000
# 	Iter:206 train-loss:0.000004 valid-loss:0.000008  train-accuracy:1.000000 valid-accuracy:1.000000
# 	Iter:216 train-loss:0.000004 valid-loss:0.000008  train-accuracy:1.000000 valid-accuracy:1.000000
# 	Iter:226 train-loss:0.000004 valid-loss:0.000008  train-accuracy:1.000000 valid-accuracy:1.000000

# %%
# Model features
model.make_inspector().features()
# Out:
# ["Autocorrelation" (1; #0),
#  "ClusterProminence" (1; #1),
#  "ClusterShade" (1; #2),
#  "ClusterTendency" (1; #3),
#  "Contrast" (1; #4),
#  "Correlation" (1; #5),
#  "DifferenceAverage" (1; #6),
#  "DifferenceEntropy" (1; #7),
#  "DifferenceVariance" (1; #8),
#  "Id" (1; #9),
#  "Idm" (1; #10),
#  "Idmn" (1; #11),
#  "Idn" (1; #12),
#  "Imc1" (1; #13),
#  "Imc2" (1; #14),
#  "InverseVariance" (1; #15),
#  "JointAverage" (1; #16),
#  "JointEnergy" (1; #17),
#  "JointEntropy" (1; #18),
#  "MCC" (1; #19),
#  "MaximumProbability" (1; #20),
#  "SumAverage" (1; #21),
#  "SumEntropy" (1; #22),
#  "SumSquares" (1; #23)]

# %%
# Feature importance
model.make_inspector().variable_importances()
# Out:
# {'INV_MEAN_MIN_DEPTH': [("Autocorrelation" (1; #0), 0.5703417246458099),
#   ("SumEntropy" (1; #22), 0.26520362088141197),
#   ("Idn" (1; #12), 0.2465206191958003),
#   ("Correlation" (1; #5), 0.21902617738759467),
#   ("JointEnergy" (1; #17), 0.21007761435522698),
#   ("ClusterShade" (1; #2), 0.20957400452122746),
#   ("SumAverage" (1; #21), 0.2079004897952839),
#   ("MCC" (1; #19), 0.20781770852355916),
#   ("JointAverage" (1; #16), 0.20644010003570124),
#   ("Imc2" (1; #14), 0.2063564573583587),
#   ("ClusterProminence" (1; #1), 0.2038267145298727),
#   ("Imc1" (1; #13), 0.2000942083516526),
#   ("JointEntropy" (1; #18), 0.19830597683794787),
#   ("DifferenceVariance" (1; #8), 0.19811600804158414),
#   ("Idm" (1; #10), 0.19804584462226338),
#   ("ClusterTendency" (1; #3), 0.1977733889852168),
#   ("MaximumProbability" (1; #20), 0.19755026912854884),
#   ("Id" (1; #9), 0.19716386208980477),
#   ("DifferenceEntropy" (1; #7), 0.1969977350629842),
#   ("InverseVariance" (1; #15), 0.19622685774025764),
#   ("SumSquares" (1; #23), 0.19573542726479565),
#   ("Contrast" (1; #4), 0.19493516367966696),
#   ("Idmn" (1; #11), 0.194918144204464),
#   ("DifferenceAverage" (1; #6), 0.1940408189816474)],
#  'SUM_SCORE': [("Autocorrelation" (1; #0), 844.9060446707914),
#   ("JointEnergy" (1; #17), 116.44515064065328),
#   ("MCC" (1; #19), 28.011045866423036),
#   ("Correlation" (1; #5), 25.62628480495159),
#   ("SumEntropy" (1; #22), 19.138005683058747),
#   ("JointAverage" (1; #16), 1.9416964936743972),
#   ("ClusterProminence" (1; #1), 1.6558582500103463),
#   ("ClusterShade" (1; #2), 1.6131770273544896),
#   ("Imc2" (1; #14), 1.5841019265474006),
#   ("MaximumProbability" (1; #20), 1.1104461689773417),
#   ("Imc1" (1; #13), 0.8899718772095312),
#   ("SumAverage" (1; #21), 0.8702208567859447),
#   ("SumSquares" (1; #23), 0.5967280455726299),
#   ("Contrast" (1; #4), 0.3552973251445495),
#   ("Id" (1; #9), 0.33855223260279554),
#   ("DifferenceVariance" (1; #8), 0.301692596000128),
#   ("JointEntropy" (1; #18), 0.2636603973963154),
#   ("InverseVariance" (1; #15), 0.22369047866778294),
#   ("Idm" (1; #10), 0.20166352205207078),
#   ("Idn" (1; #12), 0.05024813948419069),
#   ("ClusterTendency" (1; #3), 0.041965680186822785),
#   ("Idmn" (1; #11), 0.009654552433889782),
#   ("DifferenceEntropy" (1; #7), 0.0085543814153074),
#   ("DifferenceAverage" (1; #6), 0.0010723136633461123)],
#  'NUM_AS_ROOT': [("Autocorrelation" (1; #0), 142.0),
#   ("Idn" (1; #12), 33.0),
#   ("SumEntropy" (1; #22), 25.0)],
#  'NUM_NODES': [("Autocorrelation" (1; #0), 495.0),
#   ("SumEntropy" (1; #22), 309.0),
#   ("Correlation" (1; #5), 192.0),
#   ("ClusterShade" (1; #2), 163.0),
#   ("SumAverage" (1; #21), 144.0),
#   ("JointAverage" (1; #16), 136.0),
#   ("JointEnergy" (1; #17), 130.0),
#   ("Imc2" (1; #14), 113.0),
#   ("MCC" (1; #19), 101.0),
#   ("ClusterProminence" (1; #1), 98.0),
#   ("Idn" (1; #12), 97.0),
#   ("Imc1" (1; #13), 96.0),
#   ("JointEntropy" (1; #18), 71.0),
#   ("MaximumProbability" (1; #20), 65.0),
#   ("DifferenceVariance" (1; #8), 63.0),
#   ("Idm" (1; #10), 45.0),
#   ("Id" (1; #9), 44.0),
#   ("DifferenceEntropy" (1; #7), 40.0),
#   ("ClusterTendency" (1; #3), 39.0),
#   ("InverseVariance" (1; #15), 37.0),
#   ("SumSquares" (1; #23), 33.0),
#   ("Contrast" (1; #4), 32.0),
#   ("Idmn" (1; #11), 32.0),
#   ("DifferenceAverage" (1; #6), 6.0)]}

# %%
# Model self evaluation
model.make_inspector().evaluation()
# Out:
# Evaluation(num_examples=None, accuracy=1.0, loss=7.5650232247426175e-06, rmse=None, ndcg=None, aucs=None, auuc=None, qini=None)

# %%
logs = model.make_inspector().training_logs()

plt.figure(figsize=(12, 4))
plt.subplot(1, 2, 1)
plt.plot([log.num_trees for log in logs], [log.evaluation.accuracy for log in logs])
plt.xlabel("Number of trees")
plt.ylabel("Accuracy (out-of-bag)")
plt.subplot(1, 2, 2)
plt.plot([log.num_trees for log in logs], [log.evaluation.loss for log in logs])
plt.xlabel("Number of trees")
plt.ylabel("Logloss (out-of-bag)")
plt.show()

# %% [markdown]
# Calculate the score of our hold-out validation dataset

# %%
predictions = model.predict(val_ds)
y_true      = validation_data["label"]

from sklearn.metrics import roc_auc_score
ROC_AUC = roc_auc_score(y_true, predictions)
print("The ROC AUC score is %.5f" % ROC_AUC )
# Out:
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 68ms/step
# The ROC AUC score is 0.99779

# %%
# Compute binary classification metrics with sklearn
import numpy as np
from sklearn.metrics import (
    accuracy_score,
    precision_score,
    recall_score,
    f1_score,
    roc_auc_score,
    average_precision_score,
    confusion_matrix,
    classification_report,
    matthews_corrcoef,
    log_loss,
    brier_score_loss,
)

# Get predictions (probabilities or class labels)
preds = model.predict(test_ds)
# If model outputs probabilities, convert to labels by threshold 0.5
if preds.ndim == 2:
    # For TFDF classification, preds may be class probabilities with shape (N, 2)
    if preds.shape[1] == 2:
        pos_probs = preds[:, 1]
    else:
        # If single-probability column (positive class)
        pos_probs = preds[:, -1]
    y_pred = (pos_probs >= 0.5).astype(int)
else:
    # Already class labels
    y_pred = preds.astype(int)
    pos_probs = None

# Ground truth labels (must be 0/1 integers)
y_true = test_data["label"].astype(int).to_numpy()

# Core metrics
metrics = {}
metrics["accuracy"] = accuracy_score(y_true, y_pred)
metrics["precision"] = precision_score(y_true, y_pred, zero_division=0)
metrics["recall"] = recall_score(y_true, y_pred, zero_division=0)
metrics["f1"] = f1_score(y_true, y_pred, zero_division=0)
metrics["mcc"] = matthews_corrcoef(y_true, y_pred)

# Probabilistic metrics (only if we have probabilities)
if pos_probs is not None:
    metrics["roc_auc"] = roc_auc_score(y_true, pos_probs)
    metrics["pr_auc"] = average_precision_score(y_true, pos_probs)
    metrics["log_loss"] = log_loss(y_true, pos_probs, labels=[0,1])
    metrics["brier_score"] = brier_score_loss(y_true, pos_probs)

# Confusion matrix and detailed report
cm = confusion_matrix(y_true, y_pred, labels=[0,1])
report = classification_report(y_true, y_pred, digits=4)

print("Sklearn binary metrics:")
for k, v in metrics.items():
    print(f"{k}: {v:.4f}")
print("\nConfusion matrix:\n", cm)
print("\nClassification report:\n", report)
# Out:
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 73ms/step
# Sklearn binary metrics:
# accuracy: 0.9836
# precision: 0.8182
# recall: 0.8182
# f1: 0.8182
# mcc: 0.8096
# roc_auc: 0.9934
# pr_auc: 0.9006
# log_loss: 0.1618
# brier_score: 0.0167
#
# Confusion matrix:
#  [[231   2]
#  [  2   9]]
#
# Classification report:
#                precision    recall  f1-score   support
#
#            0     0.9914    0.9914    0.9914       233
#            1     0.8182    0.8182    0.8182        11
#
#     accuracy                         0.9836       244
#    macro avg     0.9048    0.9048    0.9048       244
# weighted avg     0.9836    0.9836    0.9836       244
