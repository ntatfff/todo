# %%
# Import packages and modules
import numpy  as np
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow_decision_forests as tfdf

from sklearn.model_selection import train_test_split
# Out:
# 2026-07-04 08:51:46.676476: I tensorflow/core/util/port.cc:113] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2026-07-04 08:51:46.715745: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2026-07-04 08:51:51.021445: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
# Check the version of TensorFlow Decision Forests
print("Found TensorFlow Decision Forests v" + tfdf.__version__)
# Out:
# Found TensorFlow Decision Forests v1.9.1

# %%
datasetPath = 'dataset/firstorder/kernel5-radius5/dataset.csv'

# %%
# Parameters
datasetPath = "dataset/glrlm/kernel5-radius5/500.dataset.csv"

# %%
# train/validation/test = 70/10/20
dataset = pd.read_csv(datasetPath)

train_data, temp_data = train_test_split(dataset, test_size=0.3, random_state=42)
validation_data, test_data = train_test_split(temp_data, test_size=2/3, random_state=42)

# %%
from sklearn.utils.class_weight import compute_class_weight

# tinh class weight tren tap train
classes = np.array([0, 1])
weights = compute_class_weight(class_weight="balanced", classes=classes, y=train_data["label"])
class_weight = {0: weights[0], 1: weights[1]}

# gan sample_weight cho tung dong
train_data["sample_weight"] = train_data["label"].map(class_weight)
validation_data["sample_weight"] = validation_data["label"].map(class_weight)
test_data["sample_weight"] = test_data["label"].map(class_weight)

# Convert the dataset into a TensorFlow dataset.
train_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    train_data, label="label", weight="sample_weight"
)         
val_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    validation_data, label="label", weight="sample_weight"
)
test_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    test_data, label="label", weight="sample_weight"
)
# Out:
# 2026-07-04 08:52:03.820071: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:984] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2026-07-04 08:52:03.821582: W tensorflow/core/common_runtime/gpu/gpu_device.cc:2251] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...

# %%
import keras

# %%
# %%time

# Train a Gradient Boosted Trees model.
model = tfdf.keras.GradientBoostedTreesModel()

# Add evaluation metrics
model.compile(
    metrics=["accuracy"]
)
model.fit(x=train_ds)

# # Train a Gradient Boosted Trees model.
# model = tfdf.keras.GradientBoostedTreesModel(num_trees=1500)
# model.fit(train_ds)
# Out:
# Use /tmp/tmpoqxeciud as temporary training directory
# [WARNING 26-07-04 08:52:04.0243 UTC gradient_boosted_trees.cc:1840] "goss_alpha" set but "sampling_method" not equal to "GOSS".
# [WARNING 26-07-04 08:52:04.0244 UTC gradient_boosted_trees.cc:1851] "goss_beta" set but "sampling_method" not equal to "GOSS".
# [WARNING 26-07-04 08:52:04.0244 UTC gradient_boosted_trees.cc:1865] "selective_gradient_boosting_ratio" set but "sampling_method" not equal to "SELGB".
# Reading training dataset...
# Training dataset read in 0:00:04.019636. Found 395218 examples.
# Training model...
# Model trained in 0:01:46.620833
# Compiling model...
# [INFO 26-07-04 08:53:54.6746 UTC kernel.cc:1233] Loading model from path /tmp/tmpoqxeciud/model/ with prefix 2e2ce0d9b64d43e4
# [INFO 26-07-04 08:53:54.6907 UTC quick_scorer_extended.cc:911] The binary was compiled without AVX2 support, but your CPU supports it. Enable it for faster model inference.
# [INFO 26-07-04 08:53:54.6917 UTC abstract_model.cc:1362] Engine "GradientBoostedTreesQuickScorerExtended" built
# [INFO 26-07-04 08:53:54.6917 UTC kernel.cc:1061] Use fast generic engine
# Model compiled.
# CPU times: user 13min 27s, sys: 4.83 s, total: 13min 32s
# Wall time: 1min 53s

# %%
# Evaluate the model
evaluate = model.evaluate(val_ds, return_dict=True)
print()

for name, value in evaluate.items():
    print(f"{name}: {value:.4f}")
# Out:
# WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
#  1/57 [..............................] - ETA: 2:46 - loss: 0.0000e+00 - accuracy: 0.8800
# 12/57 [=====>........................] - ETA: 0s - loss: 0.0000e+00 - accuracy: 0.8858
# 26/57 [============>.................] - ETA: 0s - loss: 0.0000e+00 - accuracy: 0.8827
# 39/57 [===================>..........] - ETA: 0s - loss: 0.0000e+00 - accuracy: 0.8840
# 52/57 [==========================>...] - ETA: 0s - loss: 0.0000e+00 - accuracy: 0.8829
# 57/57 [==============================] - 3s 4ms/step - loss: 0.0000e+00 - accuracy: 0.8835
# loss: 0.0000
# accuracy: 0.8835

# %%
# Model Summary
model.summary()
# Out:
# Model: "gradient_boosted_trees_model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
# =================================================================
# Total params: 1 (1.00 Byte)
# Trainable params: 0 (0.00 Byte)
# Non-trainable params: 1 (1.00 Byte)
# _________________________________________________________________
# Type: "GRADIENT_BOOSTED_TREES"
# Task: CLASSIFICATION
# Label: "__LABEL"
#
# Input Features (16):
# 	GrayLevelNonUniformity
# 	GrayLevelNonUniformityNormalized
# 	GrayLevelVariance
# 	HighGrayLevelRunEmphasis
# 	LongRunEmphasis
# 	LongRunHighGrayLevelEmphasis
# 	LongRunLowGrayLevelEmphasis
# 	LowGrayLevelRunEmphasis
# 	RunEntropy
# 	RunLengthNonUniformity
# 	RunLengthNonUniformityNormalized
# 	RunPercentage
# 	RunVariance
# 	ShortRunEmphasis
# 	ShortRunHighGrayLevelEmphasis
# 	ShortRunLowGrayLevelEmphasis
#
# Trained with weights
#
# Variable Importance: INV_MEAN_MIN_DEPTH:
#     1.     "LongRunHighGrayLevelEmphasis"  0.248567 ################
#     2. "RunLengthNonUniformityNormalized"  0.221009 #########
#     3.           "GrayLevelNonUniformity"  0.217884 #########
#     4.                       "RunEntropy"  0.207267 ######
#     5.    "ShortRunHighGrayLevelEmphasis"  0.200533 #####
#     6.     "ShortRunLowGrayLevelEmphasis"  0.199510 #####
#     7.                "GrayLevelVariance"  0.195296 ####
#     8. "GrayLevelNonUniformityNormalized"  0.189624 ###
#     9.                 "ShortRunEmphasis"  0.189483 ##
#    10.      "LongRunLowGrayLevelEmphasis"  0.189444 ##
#    11.          "LowGrayLevelRunEmphasis"  0.186298 ##
#    12.                      "RunVariance"  0.185863 ##
#    13.           "RunLengthNonUniformity"  0.181634 #
#    14.         "HighGrayLevelRunEmphasis"  0.181278 #
#    15.                  "LongRunEmphasis"  0.181276 #
#    16.                    "RunPercentage"  0.175955
#
# Variable Importance: NUM_AS_ROOT:
#     1.     "LongRunHighGrayLevelEmphasis" 73.000000 ################
#     2. "RunLengthNonUniformityNormalized" 52.000000 ###########
#     3.           "GrayLevelNonUniformity" 42.000000 #########
#     4.     "ShortRunLowGrayLevelEmphasis" 26.000000 #####
#     5.                       "RunEntropy" 23.000000 ####
#     6.                 "ShortRunEmphasis" 19.000000 ####
#     7.          "LowGrayLevelRunEmphasis" 18.000000 ###
#     8.           "RunLengthNonUniformity" 10.000000 ##
#     9.    "ShortRunHighGrayLevelEmphasis"  9.000000 #
#    10. "GrayLevelNonUniformityNormalized"  8.000000 #
#    11.      "LongRunLowGrayLevelEmphasis"  7.000000 #
#    12.                      "RunVariance"  6.000000 #
#    13.                "GrayLevelVariance"  3.000000
#    14.         "HighGrayLevelRunEmphasis"  3.000000
#    15.                    "RunPercentage"  1.000000
#
# Variable Importance: NUM_NODES:
#     1.     "LongRunHighGrayLevelEmphasis" 1071.000000 ################
#     2.                       "RunEntropy" 853.000000 ###########
#     3.                "GrayLevelVariance" 758.000000 ##########
#     4.     "ShortRunLowGrayLevelEmphasis" 686.000000 ########
#     5.           "GrayLevelNonUniformity" 672.000000 ########
#     6.    "ShortRunHighGrayLevelEmphasis" 655.000000 ########
#     7.      "LongRunLowGrayLevelEmphasis" 584.000000 ######
#     8. "RunLengthNonUniformityNormalized" 473.000000 ####
#     9. "GrayLevelNonUniformityNormalized" 430.000000 ####
#    10.                      "RunVariance" 430.000000 ####
#    11.          "LowGrayLevelRunEmphasis" 387.000000 ###
#    12.         "HighGrayLevelRunEmphasis" 341.000000 ##
#    13.                 "ShortRunEmphasis" 333.000000 ##
#    14.                  "LongRunEmphasis" 304.000000 #
#    15.           "RunLengthNonUniformity" 237.000000
#    16.                    "RunPercentage" 206.000000
#
# Variable Importance: SUM_SCORE:
#     1.     "LongRunHighGrayLevelEmphasis" 65059.920511 ################
#     2.          "LowGrayLevelRunEmphasis" 52069.865142 ############
#     3.     "ShortRunLowGrayLevelEmphasis" 49217.801816 ############
#     4.    "ShortRunHighGrayLevelEmphasis" 39623.319602 #########
#     5.                       "RunEntropy" 30987.004303 #######
#     6.           "GrayLevelNonUniformity" 20918.566630 ####
#     7.                      "RunVariance" 17420.342187 ###
#     8.                "GrayLevelVariance" 9288.257074 #
#     9.      "LongRunLowGrayLevelEmphasis" 7466.606097 #
#    10. "RunLengthNonUniformityNormalized" 6196.773652 #
#    11.         "HighGrayLevelRunEmphasis" 5989.938344 #
#    12.                 "ShortRunEmphasis" 5697.405812 #
#    13.                  "LongRunEmphasis" 3325.264804
#    14. "GrayLevelNonUniformityNormalized" 2564.021544
#    15.           "RunLengthNonUniformity" 1702.475460
#    16.                    "RunPercentage" 1643.092009
#
#
#
# Loss: BINOMIAL_LOG_LIKELIHOOD
# Validation loss value: 0.609227
# Number of trees per iteration: 1
# Node format: NOT_SET
# Number of trees: 300
# Total number of nodes: 17140
#
# Number of nodes by tree:
# Count: 300 Average: 57.1333 StdDev: 6.89025
# Min: 33 Max: 63 Ignored: 0
# ----------------------------------------------
# [ 33, 34)  5   1.67%   1.67% #
# [ 34, 36)  2   0.67%   2.33%
# [ 36, 37)  0   0.00%   2.33%
# [ 37, 39)  0   0.00%   2.33%
# [ 39, 40)  1   0.33%   2.67%
# [ 40, 42)  2   0.67%   3.33%
# [ 42, 43)  0   0.00%   3.33%
# [ 43, 45)  5   1.67%   5.00% #
# [ 45, 46)  5   1.67%   6.67% #
# [ 46, 48) 17   5.67%  12.33% ##
# [ 48, 50) 17   5.67%  18.00% ##
# [ 50, 51)  0   0.00%  18.00%
# [ 51, 53) 10   3.33%  21.33% #
# [ 53, 54) 15   5.00%  26.33% ##
# [ 54, 56) 17   5.67%  32.00% ##
# [ 56, 57)  0   0.00%  32.00%
# [ 57, 59) 25   8.33%  40.33% ###
# [ 59, 60) 33  11.00%  51.33% ###
# [ 60, 62) 49  16.33%  67.67% #####
# [ 62, 63] 97  32.33% 100.00% ##########
#
# Depth by leafs:
# Count: 8720 Average: 4.9297 StdDev: 0.340989
# Min: 2 Max: 5 Ignored: 0
# ----------------------------------------------
# [ 2, 3)   45   0.52%   0.52%
# [ 3, 4)   87   1.00%   1.51%
# [ 4, 5)  304   3.49%   5.00%
# [ 5, 5] 8284  95.00% 100.00% ##########
#
# Number of training obs by leaf:
# Count: 8720 Average: 12233.8 StdDev: 43535.7
# Min: 5 Max: 352318 Ignored: 0
# ----------------------------------------------
# [      5,  17620) 7731  88.66%  88.66% ##########
# [  17620,  35236)  410   4.70%  93.36% #
# [  35236,  52852)  150   1.72%  95.08%
# [  52852,  70467)   58   0.67%  95.75%
# [  70467,  88083)   47   0.54%  96.28%
# [  88083, 105699)   30   0.34%  96.63%
# [ 105699, 123314)   29   0.33%  96.96%
# [ 123314, 140930)   28   0.32%  97.28%
# [ 140930, 158546)   23   0.26%  97.55%
# [ 158546, 176162)   24   0.28%  97.82%
# [ 176162, 193777)   21   0.24%  98.06%
# [ 193777, 211393)   18   0.21%  98.27%
# [ 211393, 229009)    8   0.09%  98.36%
# [ 229009, 246624)   19   0.22%  98.58%
# [ 246624, 264240)   20   0.23%  98.81%
# [ 264240, 281856)   17   0.19%  99.00%
# [ 281856, 299471)   22   0.25%  99.25%
# [ 299471, 317087)   21   0.24%  99.50%
# [ 317087, 334703)   16   0.18%  99.68%
# [ 334703, 352318]   28   0.32% 100.00%
#
# Attribute in nodes:
# 	1071 : LongRunHighGrayLevelEmphasis [NUMERICAL]
# 	853 : RunEntropy [NUMERICAL]
# 	758 : GrayLevelVariance [NUMERICAL]
# 	686 : ShortRunLowGrayLevelEmphasis [NUMERICAL]
# 	672 : GrayLevelNonUniformity [NUMERICAL]
# 	655 : ShortRunHighGrayLevelEmphasis [NUMERICAL]
# 	584 : LongRunLowGrayLevelEmphasis [NUMERICAL]
# 	473 : RunLengthNonUniformityNormalized [NUMERICAL]
# 	430 : RunVariance [NUMERICAL]
# 	430 : GrayLevelNonUniformityNormalized [NUMERICAL]
# 	387 : LowGrayLevelRunEmphasis [NUMERICAL]
# 	341 : HighGrayLevelRunEmphasis [NUMERICAL]
# 	333 : ShortRunEmphasis [NUMERICAL]
# 	304 : LongRunEmphasis [NUMERICAL]
# 	237 : RunLengthNonUniformity [NUMERICAL]
# 	206 : RunPercentage [NUMERICAL]
#
# Attribute in nodes with depth <= 0:
# 	73 : LongRunHighGrayLevelEmphasis [NUMERICAL]
# 	52 : RunLengthNonUniformityNormalized [NUMERICAL]
# 	42 : GrayLevelNonUniformity [NUMERICAL]
# 	26 : ShortRunLowGrayLevelEmphasis [NUMERICAL]
# 	23 : RunEntropy [NUMERICAL]
# 	19 : ShortRunEmphasis [NUMERICAL]
# 	18 : LowGrayLevelRunEmphasis [NUMERICAL]
# 	10 : RunLengthNonUniformity [NUMERICAL]
# 	9 : ShortRunHighGrayLevelEmphasis [NUMERICAL]
# 	8 : GrayLevelNonUniformityNormalized [NUMERICAL]
# 	7 : LongRunLowGrayLevelEmphasis [NUMERICAL]
# 	6 : RunVariance [NUMERICAL]
# 	3 : HighGrayLevelRunEmphasis [NUMERICAL]
# 	3 : GrayLevelVariance [NUMERICAL]
# 	1 : RunPercentage [NUMERICAL]
#
# Attribute in nodes with depth <= 1:
# 	139 : LongRunHighGrayLevelEmphasis [NUMERICAL]
# 	111 : RunLengthNonUniformityNormalized [NUMERICAL]
# 	89 : GrayLevelNonUniformity [NUMERICAL]
# 	73 : ShortRunHighGrayLevelEmphasis [NUMERICAL]
# 	73 : RunEntropy [NUMERICAL]
# 	52 : ShortRunEmphasis [NUMERICAL]
# 	51 : GrayLevelVariance [NUMERICAL]
# 	48 : ShortRunLowGrayLevelEmphasis [NUMERICAL]
# 	45 : GrayLevelNonUniformityNormalized [NUMERICAL]
# 	43 : LongRunLowGrayLevelEmphasis [NUMERICAL]
# 	39 : LongRunEmphasis [NUMERICAL]
# 	36 : RunVariance [NUMERICAL]
# 	32 : RunLengthNonUniformity [NUMERICAL]
# 	27 : HighGrayLevelRunEmphasis [NUMERICAL]
# 	25 : LowGrayLevelRunEmphasis [NUMERICAL]
# 	17 : RunPercentage [NUMERICAL]
#
# Attribute in nodes with depth <= 2:
# 	288 : LongRunHighGrayLevelEmphasis [NUMERICAL]
# 	221 : GrayLevelNonUniformity [NUMERICAL]
# 	182 : RunEntropy [NUMERICAL]
# 	168 : RunLengthNonUniformityNormalized [NUMERICAL]
# 	164 : ShortRunHighGrayLevelEmphasis [NUMERICAL]
# 	150 : GrayLevelVariance [NUMERICAL]
# 	133 : GrayLevelNonUniformityNormalized [NUMERICAL]
# 	124 : LongRunLowGrayLevelEmphasis [NUMERICAL]
# 	120 : ShortRunLowGrayLevelEmphasis [NUMERICAL]
# 	91 : RunVariance [NUMERICAL]
# 	88 : ShortRunEmphasis [NUMERICAL]
# 	83 : HighGrayLevelRunEmphasis [NUMERICAL]
# 	74 : LongRunEmphasis [NUMERICAL]
# 	71 : LowGrayLevelRunEmphasis [NUMERICAL]
# 	56 : RunLengthNonUniformity [NUMERICAL]
# 	42 : RunPercentage [NUMERICAL]
#
# Attribute in nodes with depth <= 3:
# 	570 : LongRunHighGrayLevelEmphasis [NUMERICAL]
# 	413 : RunEntropy [NUMERICAL]
# 	379 : GrayLevelVariance [NUMERICAL]
# 	365 : GrayLevelNonUniformity [NUMERICAL]
# 	342 : ShortRunHighGrayLevelEmphasis [NUMERICAL]
# 	313 : ShortRunLowGrayLevelEmphasis [NUMERICAL]
# 	285 : RunLengthNonUniformityNormalized [NUMERICAL]
# 	285 : LongRunLowGrayLevelEmphasis [NUMERICAL]
# 	230 : GrayLevelNonUniformityNormalized [NUMERICAL]
# 	200 : RunVariance [NUMERICAL]
# 	179 : ShortRunEmphasis [NUMERICAL]
# 	177 : HighGrayLevelRunEmphasis [NUMERICAL]
# 	164 : LowGrayLevelRunEmphasis [NUMERICAL]
# 	149 : LongRunEmphasis [NUMERICAL]
# 	127 : RunLengthNonUniformity [NUMERICAL]
# 	100 : RunPercentage [NUMERICAL]
#
# Attribute in nodes with depth <= 5:
# 	1071 : LongRunHighGrayLevelEmphasis [NUMERICAL]
# 	853 : RunEntropy [NUMERICAL]
# 	758 : GrayLevelVariance [NUMERICAL]
# 	686 : ShortRunLowGrayLevelEmphasis [NUMERICAL]
# 	672 : GrayLevelNonUniformity [NUMERICAL]
# 	655 : ShortRunHighGrayLevelEmphasis [NUMERICAL]
# 	584 : LongRunLowGrayLevelEmphasis [NUMERICAL]
# 	473 : RunLengthNonUniformityNormalized [NUMERICAL]
# 	430 : RunVariance [NUMERICAL]
# 	430 : GrayLevelNonUniformityNormalized [NUMERICAL]
# 	387 : LowGrayLevelRunEmphasis [NUMERICAL]
# 	341 : HighGrayLevelRunEmphasis [NUMERICAL]
# 	333 : ShortRunEmphasis [NUMERICAL]
# 	304 : LongRunEmphasis [NUMERICAL]
# 	237 : RunLengthNonUniformity [NUMERICAL]
# 	206 : RunPercentage [NUMERICAL]
#
# Condition type in nodes:
# 	8420 : HigherCondition
# Condition type in nodes with depth <= 0:
# 	300 : HigherCondition
# Condition type in nodes with depth <= 1:
# 	900 : HigherCondition
# Condition type in nodes with depth <= 2:
# 	2055 : HigherCondition
# Condition type in nodes with depth <= 3:
# 	4278 : HigherCondition
# Condition type in nodes with depth <= 5:
# 	8420 : HigherCondition
#
# Training logs:
# Number of iteration to final model: 300
# 	Iter:1 train-loss:1.297780 valid-loss:1.298264  train-accuracy:0.806673 valid-accuracy:0.805816
# 	Iter:2 train-loss:1.225048 valid-loss:1.226181  train-accuracy:0.808778 valid-accuracy:0.807817
# 	Iter:3 train-loss:1.164660 valid-loss:1.166307  train-accuracy:0.809687 valid-accuracy:0.809102
# 	Iter:4 train-loss:1.113675 valid-loss:1.115249  train-accuracy:0.816340 valid-accuracy:0.815029
# 	Iter:5 train-loss:1.069351 valid-loss:1.071666  train-accuracy:0.821035 valid-accuracy:0.821474
# 	Iter:6 train-loss:1.031832 valid-loss:1.034700  train-accuracy:0.822595 valid-accuracy:0.822513
# 	Iter:16 train-loss:0.815944 valid-loss:0.821490  train-accuracy:0.839285 valid-accuracy:0.840841
# 	Iter:26 train-loss:0.732529 valid-loss:0.738533  train-accuracy:0.849372 valid-accuracy:0.848454
# 	Iter:36 train-loss:0.691456 valid-loss:0.700044  train-accuracy:0.854298 valid-accuracy:0.851026
# 	Iter:46 train-loss:0.666769 valid-loss:0.678112  train-accuracy:0.858432 valid-accuracy:0.855195
# 	Iter:56 train-loss:0.647404 valid-loss:0.662674  train-accuracy:0.862054 valid-accuracy:0.858234
# 	Iter:66 train-loss:0.633743 valid-loss:0.652273  train-accuracy:0.864964 valid-accuracy:0.860453
# 	Iter:76 train-loss:0.623141 valid-loss:0.644960  train-accuracy:0.866916 valid-accuracy:0.860877
# 	Iter:86 train-loss:0.614073 valid-loss:0.638754  train-accuracy:0.869250 valid-accuracy:0.861674
# 	Iter:96 train-loss:0.606236 valid-loss:0.633704  train-accuracy:0.871158 valid-accuracy:0.863501
# 	Iter:106 train-loss:0.599905 valid-loss:0.630622  train-accuracy:0.872823 valid-accuracy:0.863130
# 	Iter:116 train-loss:0.593590 valid-loss:0.627749  train-accuracy:0.873911 valid-accuracy:0.864330
# 	Iter:126 train-loss:0.588077 valid-loss:0.625945  train-accuracy:0.875595 valid-accuracy:0.865662
# 	Iter:136 train-loss:0.583059 valid-loss:0.623740  train-accuracy:0.876851 valid-accuracy:0.866662
# 	Iter:146 train-loss:0.578529 valid-loss:0.622249  train-accuracy:0.877703 valid-accuracy:0.867113
# 	Iter:156 train-loss:0.574346 valid-loss:0.619940  train-accuracy:0.878775 valid-accuracy:0.867340
# 	Iter:166 train-loss:0.569954 valid-loss:0.618536  train-accuracy:0.879845 valid-accuracy:0.867536
# 	Iter:176 train-loss:0.566362 valid-loss:0.617413  train-accuracy:0.880509 valid-accuracy:0.867828
# 	Iter:186 train-loss:0.562104 valid-loss:0.616537  train-accuracy:0.881640 valid-accuracy:0.867707
# 	Iter:196 train-loss:0.558411 valid-loss:0.615953  train-accuracy:0.882513 valid-accuracy:0.868122
# 	Iter:206 train-loss:0.554821 valid-loss:0.614834  train-accuracy:0.883266 valid-accuracy:0.868436
# 	Iter:216 train-loss:0.551229 valid-loss:0.614330  train-accuracy:0.884135 valid-accuracy:0.868328
# 	Iter:226 train-loss:0.547232 valid-loss:0.613437  train-accuracy:0.884937 valid-accuracy:0.868424
# 	Iter:236 train-loss:0.543891 valid-loss:0.613119  train-accuracy:0.885513 valid-accuracy:0.867975
# 	Iter:246 train-loss:0.540829 valid-loss:0.612856  train-accuracy:0.886173 valid-accuracy:0.867794
# 	Iter:256 train-loss:0.538312 valid-loss:0.612636  train-accuracy:0.887263 valid-accuracy:0.868412
# 	Iter:266 train-loss:0.535639 valid-loss:0.612229  train-accuracy:0.887674 valid-accuracy:0.868939
# 	Iter:276 train-loss:0.531974 valid-loss:0.611375  train-accuracy:0.888841 valid-accuracy:0.869067
# 	Iter:286 train-loss:0.529323 valid-loss:0.610496  train-accuracy:0.889212 valid-accuracy:0.869023
# 	Iter:296 train-loss:0.526206 valid-loss:0.609392  train-accuracy:0.890166 valid-accuracy:0.869350

# %%
# Model features
model.make_inspector().features()
# Out:
# ["GrayLevelNonUniformity" (1; #0),
#  "GrayLevelNonUniformityNormalized" (1; #1),
#  "GrayLevelVariance" (1; #2),
#  "HighGrayLevelRunEmphasis" (1; #3),
#  "LongRunEmphasis" (1; #4),
#  "LongRunHighGrayLevelEmphasis" (1; #5),
#  "LongRunLowGrayLevelEmphasis" (1; #6),
#  "LowGrayLevelRunEmphasis" (1; #7),
#  "RunEntropy" (1; #8),
#  "RunLengthNonUniformity" (1; #9),
#  "RunLengthNonUniformityNormalized" (1; #10),
#  "RunPercentage" (1; #11),
#  "RunVariance" (1; #12),
#  "ShortRunEmphasis" (1; #13),
#  "ShortRunHighGrayLevelEmphasis" (1; #14),
#  "ShortRunLowGrayLevelEmphasis" (1; #15)]

# %%
# Feature importance
model.make_inspector().variable_importances()
# Out:
# {'INV_MEAN_MIN_DEPTH': [("LongRunHighGrayLevelEmphasis" (1; #5),
#    0.2485670052808447),
#   ("RunLengthNonUniformityNormalized" (1; #10), 0.2210090432906891),
#   ("GrayLevelNonUniformity" (1; #0), 0.21788416163167343),
#   ("RunEntropy" (1; #8), 0.20726669680715157),
#   ("ShortRunHighGrayLevelEmphasis" (1; #14), 0.20053322356201136),
#   ("ShortRunLowGrayLevelEmphasis" (1; #15), 0.1995097644991402),
#   ("GrayLevelVariance" (1; #2), 0.19529613911674046),
#   ("GrayLevelNonUniformityNormalized" (1; #1), 0.1896240277286077),
#   ("ShortRunEmphasis" (1; #13), 0.18948250595889568),
#   ("LongRunLowGrayLevelEmphasis" (1; #6), 0.18944416525747695),
#   ("LowGrayLevelRunEmphasis" (1; #7), 0.18629827285467182),
#   ("RunVariance" (1; #12), 0.18586290728406119),
#   ("RunLengthNonUniformity" (1; #9), 0.18163427875074853),
#   ("HighGrayLevelRunEmphasis" (1; #3), 0.18127838987741868),
#   ("LongRunEmphasis" (1; #4), 0.18127606692855205),
#   ("RunPercentage" (1; #11), 0.17595457543054271)],
#  'SUM_SCORE': [("LongRunHighGrayLevelEmphasis" (1; #5), 65059.92051146239),
#   ("LowGrayLevelRunEmphasis" (1; #7), 52069.86514196693),
#   ("ShortRunLowGrayLevelEmphasis" (1; #15), 49217.80181583003),
#   ("ShortRunHighGrayLevelEmphasis" (1; #14), 39623.319602069976),
#   ("RunEntropy" (1; #8), 30987.004302688474),
#   ("GrayLevelNonUniformity" (1; #0), 20918.56663022552),
#   ("RunVariance" (1; #12), 17420.342187458293),
#   ("GrayLevelVariance" (1; #2), 9288.257073991954),
#   ("LongRunLowGrayLevelEmphasis" (1; #6), 7466.606096911968),
#   ("RunLengthNonUniformityNormalized" (1; #10), 6196.773652190273),
#   ("HighGrayLevelRunEmphasis" (1; #3), 5989.938344284548),
#   ("ShortRunEmphasis" (1; #13), 5697.405811506582),
#   ("LongRunEmphasis" (1; #4), 3325.2648040292315),
#   ("GrayLevelNonUniformityNormalized" (1; #1), 2564.0215437273655),
#   ("RunLengthNonUniformity" (1; #9), 1702.475460419258),
#   ("RunPercentage" (1; #11), 1643.0920086663884)],
#  'NUM_AS_ROOT': [("LongRunHighGrayLevelEmphasis" (1; #5), 73.0),
#   ("RunLengthNonUniformityNormalized" (1; #10), 52.0),
#   ("GrayLevelNonUniformity" (1; #0), 42.0),
#   ("ShortRunLowGrayLevelEmphasis" (1; #15), 26.0),
#   ("RunEntropy" (1; #8), 23.0),
#   ("ShortRunEmphasis" (1; #13), 19.0),
#   ("LowGrayLevelRunEmphasis" (1; #7), 18.0),
#   ("RunLengthNonUniformity" (1; #9), 10.0),
#   ("ShortRunHighGrayLevelEmphasis" (1; #14), 9.0),
#   ("GrayLevelNonUniformityNormalized" (1; #1), 8.0),
#   ("LongRunLowGrayLevelEmphasis" (1; #6), 7.0),
#   ("RunVariance" (1; #12), 6.0),
#   ("GrayLevelVariance" (1; #2), 3.0),
#   ("HighGrayLevelRunEmphasis" (1; #3), 3.0),
#   ("RunPercentage" (1; #11), 1.0)],
#  'NUM_NODES': [("LongRunHighGrayLevelEmphasis" (1; #5), 1071.0),
#   ("RunEntropy" (1; #8), 853.0),
#   ("GrayLevelVariance" (1; #2), 758.0),
#   ("ShortRunLowGrayLevelEmphasis" (1; #15), 686.0),
#   ("GrayLevelNonUniformity" (1; #0), 672.0),
#   ("ShortRunHighGrayLevelEmphasis" (1; #14), 655.0),
#   ("LongRunLowGrayLevelEmphasis" (1; #6), 584.0),
#   ("RunLengthNonUniformityNormalized" (1; #10), 473.0),
#   ("GrayLevelNonUniformityNormalized" (1; #1), 430.0),
#   ("RunVariance" (1; #12), 430.0),
#   ("LowGrayLevelRunEmphasis" (1; #7), 387.0),
#   ("HighGrayLevelRunEmphasis" (1; #3), 341.0),
#   ("ShortRunEmphasis" (1; #13), 333.0),
#   ("LongRunEmphasis" (1; #4), 304.0),
#   ("RunLengthNonUniformity" (1; #9), 237.0),
#   ("RunPercentage" (1; #11), 206.0)]}

# %%
# Model self evaluation
model.make_inspector().evaluation()
# Out:
# Evaluation(num_examples=None, accuracy=0.8691643476486206, loss=0.6092274785041809, rmse=None, ndcg=None, aucs=None, auuc=None, qini=None)

# %%
logs = model.make_inspector().training_logs()

plt.figure(figsize=(12, 4))
plt.subplot(1, 2, 1)
plt.plot([log.num_trees for log in logs], [log.evaluation.accuracy for log in logs])
plt.xlabel("Number of trees")
plt.ylabel("Accuracy (out-of-bag)")
plt.subplot(1, 2, 2)
plt.plot([log.num_trees for log in logs], [log.evaluation.loss for log in logs])
plt.xlabel("Number of trees")
plt.ylabel("Logloss (out-of-bag)")
plt.show()

# %% [markdown]
# Calculate the score of our hold-out validation dataset

# %%
predictions = model.predict(val_ds)
y_true      = validation_data["label"]

from sklearn.metrics import roc_auc_score
ROC_AUC = roc_auc_score(y_true, predictions)
print("The ROC AUC score is %.5f" % ROC_AUC )
# Out:
#  1/57 [..............................] - ETA: 3s
# 13/57 [=====>........................] - ETA: 0s
# 26/57 [============>.................] - ETA: 0s
# 38/57 [===================>..........] - ETA: 0s
# 50/57 [=========================>....] - ETA: 0s
# 57/57 [==============================] - 0s 4ms/step
# The ROC AUC score is 0.94231

# %%
# Compute binary classification metrics with sklearn
import numpy as np
from sklearn.metrics import (
    accuracy_score,
    precision_score,
    recall_score,
    f1_score,
    roc_auc_score,
    average_precision_score,
    confusion_matrix,
    classification_report,
    matthews_corrcoef,
    log_loss,
    brier_score_loss,
)

# Get predictions (probabilities or class labels)
preds = model.predict(test_ds)
# If model outputs probabilities, convert to labels by threshold 0.5
if preds.ndim == 2:
    # For TFDF classification, preds may be class probabilities with shape (N, 2)
    if preds.shape[1] == 2:
        pos_probs = preds[:, 1]
    else:
        # If single-probability column (positive class)
        pos_probs = preds[:, -1]
    y_pred = (pos_probs >= 0.5).astype(int)
else:
    # Already class labels
    y_pred = preds.astype(int)
    pos_probs = None

# Ground truth labels (must be 0/1 integers)
y_true = test_data["label"].astype(int).to_numpy()

# Core metrics
metrics = {}
metrics["accuracy"] = accuracy_score(y_true, y_pred)
metrics["precision"] = precision_score(y_true, y_pred, zero_division=0)
metrics["recall"] = recall_score(y_true, y_pred, zero_division=0)
metrics["f1"] = f1_score(y_true, y_pred, zero_division=0)
metrics["mcc"] = matthews_corrcoef(y_true, y_pred)

# Probabilistic metrics (only if we have probabilities)
if pos_probs is not None:
    metrics["roc_auc"] = roc_auc_score(y_true, pos_probs)
    metrics["pr_auc"] = average_precision_score(y_true, pos_probs)
    metrics["log_loss"] = log_loss(y_true, pos_probs, labels=[0,1])
    metrics["brier_score"] = brier_score_loss(y_true, pos_probs)

# Confusion matrix and detailed report
cm = confusion_matrix(y_true, y_pred, labels=[0,1])
report = classification_report(y_true, y_pred, digits=4)

print("Sklearn binary metrics:")
for k, v in metrics.items():
    print(f"{k}: {v:.4f}")
print("\nConfusion matrix:\n", cm)
print("\nClassification report:\n", report)
# Out:
#   1/113 [..............................] - ETA: 7s
#  14/113 [==>...........................] - ETA: 0s
#  27/113 [======>.......................] - ETA: 0s
#  40/113 [=========>....................] - ETA: 0s
#  52/113 [============>.................] - ETA: 0s
#  65/113 [================>.............] - ETA: 0s
#  77/113 [===================>..........] - ETA: 0s
#  90/113 [======================>.......] - ETA: 0s
# 102/113 [==========================>...] - ETA: 0s
# 113/113 [==============================] - 1s 4ms/step
# Sklearn binary metrics:
# accuracy: 0.8813
# precision: 0.3308
# recall: 0.8474
# f1: 0.4758
# mcc: 0.4830
# roc_auc: 0.9415
# pr_auc: 0.6613
# log_loss: 0.2843
# brier_score: 0.0867
#
# Confusion matrix:
#  [[93429 12310]
#  [ 1096  6085]]
#
# Classification report:
#                precision    recall  f1-score   support
#
#            0     0.9884    0.8836    0.9331    105739
#            1     0.3308    0.8474    0.4758      7181
#
#     accuracy                         0.8813    112920
#    macro avg     0.6596    0.8655    0.7044    112920
# weighted avg     0.9466    0.8813    0.9040    112920
