# %%
# Import packages and modules
import numpy  as np
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow_decision_forests as tfdf

from sklearn.model_selection import train_test_split
# Out:
# 2026-07-04 08:36:26.661349: I tensorflow/core/util/port.cc:113] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2026-07-04 08:36:26.702276: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2026-07-04 08:36:30.987239: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
# Check the version of TensorFlow Decision Forests
print("Found TensorFlow Decision Forests v" + tfdf.__version__)
# Out:
# Found TensorFlow Decision Forests v1.9.1

# %%
datasetPath = 'dataset/firstorder/kernel5-radius5/dataset.csv'

# %%
# Parameters
datasetPath = "dataset/gldm/kernel5-radius5/400.dataset.csv"

# %%
# train/validation/test = 70/10/20
dataset = pd.read_csv(datasetPath)

train_data, temp_data = train_test_split(dataset, test_size=0.3, random_state=42)
validation_data, test_data = train_test_split(temp_data, test_size=2/3, random_state=42)

# %%
from sklearn.utils.class_weight import compute_class_weight

# tinh class weight tren tap train
classes = np.array([0, 1])
weights = compute_class_weight(class_weight="balanced", classes=classes, y=train_data["label"])
class_weight = {0: weights[0], 1: weights[1]}

# gan sample_weight cho tung dong
train_data["sample_weight"] = train_data["label"].map(class_weight)
validation_data["sample_weight"] = validation_data["label"].map(class_weight)
test_data["sample_weight"] = test_data["label"].map(class_weight)

# Convert the dataset into a TensorFlow dataset.
train_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    train_data, label="label", weight="sample_weight"
)         
val_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    validation_data, label="label", weight="sample_weight"
)
test_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    test_data, label="label", weight="sample_weight"
)
# Out:
# 2026-07-04 08:36:43.368301: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:984] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2026-07-04 08:36:43.369681: W tensorflow/core/common_runtime/gpu/gpu_device.cc:2251] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...

# %%
import keras

# %%
# %%time

# Train a Gradient Boosted Trees model.
model = tfdf.keras.GradientBoostedTreesModel()

# Add evaluation metrics
model.compile(
    metrics=["accuracy"]
)
model.fit(x=train_ds)

# # Train a Gradient Boosted Trees model.
# model = tfdf.keras.GradientBoostedTreesModel(num_trees=1500)
# model.fit(train_ds)
# Out:
# Use /tmp/tmpyb5rpmgm as temporary training directory
# Reading training dataset...
# [WARNING 26-07-04 08:36:43.5384 UTC gradient_boosted_trees.cc:1840] "goss_alpha" set but "sampling_method" not equal to "GOSS".
# [WARNING 26-07-04 08:36:43.5384 UTC gradient_boosted_trees.cc:1851] "goss_beta" set but "sampling_method" not equal to "GOSS".
# [WARNING 26-07-04 08:36:43.5384 UTC gradient_boosted_trees.cc:1865] "selective_gradient_boosting_ratio" set but "sampling_method" not equal to "SELGB".
# Training dataset read in 0:00:03.572902. Found 315452 examples.
# Training model...
# Model trained in 0:01:02.665053
# Compiling model...
# [INFO 26-07-04 08:37:49.7883 UTC kernel.cc:1233] Loading model from path /tmp/tmpyb5rpmgm/model/ with prefix 00b836ffdeb14ead
# [INFO 26-07-04 08:37:49.7988 UTC quick_scorer_extended.cc:911] The binary was compiled without AVX2 support, but your CPU supports it. Enable it for faster model inference.
# [INFO 26-07-04 08:37:49.7996 UTC abstract_model.cc:1362] Engine "GradientBoostedTreesQuickScorerExtended" built
# [INFO 26-07-04 08:37:49.7997 UTC kernel.cc:1061] Use fast generic engine
# Model compiled.
# CPU times: user 7min 28s, sys: 3.12 s, total: 7min 31s
# Wall time: 1min 24s

# %%
# Evaluate the model
evaluate = model.evaluate(val_ds, return_dict=True)
print()

for name, value in evaluate.items():
    print(f"{name}: {value:.4f}")
# Out:
# WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
#  1/46 [..............................] - ETA: 2:10 - loss: 0.0000e+00 - accuracy: 0.9020
# 15/46 [========>.....................] - ETA: 0s - loss: 0.0000e+00 - accuracy: 0.8876
# 29/46 [=================>............] - ETA: 0s - loss: 0.0000e+00 - accuracy: 0.8897
# 43/46 [===========================>..] - ETA: 0s - loss: 0.0000e+00 - accuracy: 0.8881
# 46/46 [==============================] - 3s 4ms/step - loss: 0.0000e+00 - accuracy: 0.8888
# loss: 0.0000
# accuracy: 0.8888

# %%
# Model Summary
model.summary()
# Out:
# Model: "gradient_boosted_trees_model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
# =================================================================
# Total params: 1 (1.00 Byte)
# Trainable params: 0 (0.00 Byte)
# Non-trainable params: 1 (1.00 Byte)
# _________________________________________________________________
# Type: "GRADIENT_BOOSTED_TREES"
# Task: CLASSIFICATION
# Label: "__LABEL"
#
# Input Features (14):
# 	DependenceEntropy
# 	DependenceNonUniformity
# 	DependenceNonUniformityNormalized
# 	DependenceVariance
# 	GrayLevelNonUniformity
# 	GrayLevelVariance
# 	HighGrayLevelEmphasis
# 	LargeDependenceEmphasis
# 	LargeDependenceHighGrayLevelEmphasis
# 	LargeDependenceLowGrayLevelEmphasis
# 	LowGrayLevelEmphasis
# 	SmallDependenceEmphasis
# 	SmallDependenceHighGrayLevelEmphasis
# 	SmallDependenceLowGrayLevelEmphasis
#
# Trained with weights
#
# Variable Importance: INV_MEAN_MIN_DEPTH:
#     1. "LargeDependenceHighGrayLevelEmphasis"  0.250396 ################
#     2.                    "DependenceEntropy"  0.228407 ###########
#     3.              "SmallDependenceEmphasis"  0.219169 #########
#     4.  "SmallDependenceLowGrayLevelEmphasis"  0.215765 ########
#     5.               "GrayLevelNonUniformity"  0.215363 ########
#     6. "SmallDependenceHighGrayLevelEmphasis"  0.203374 ######
#     7.                   "DependenceVariance"  0.199276 #####
#     8.                "HighGrayLevelEmphasis"  0.199225 #####
#     9.                 "LowGrayLevelEmphasis"  0.195636 ####
#    10.                    "GrayLevelVariance"  0.190663 ###
#    11.  "LargeDependenceLowGrayLevelEmphasis"  0.185241 ##
#    12.              "LargeDependenceEmphasis"  0.178426 #
#    13.              "DependenceNonUniformity"  0.173723
#    14.    "DependenceNonUniformityNormalized"  0.173439
#
# Variable Importance: NUM_AS_ROOT:
#     1. "LargeDependenceHighGrayLevelEmphasis" 49.000000 ################
#     2.               "GrayLevelNonUniformity" 32.000000 ##########
#     3.                    "DependenceEntropy" 24.000000 #######
#     4.  "SmallDependenceLowGrayLevelEmphasis" 24.000000 #######
#     5.                   "DependenceVariance" 21.000000 ######
#     6.                 "LowGrayLevelEmphasis" 19.000000 ######
#     7.                "HighGrayLevelEmphasis" 13.000000 ####
#     8.              "SmallDependenceEmphasis" 10.000000 ###
#     9. "SmallDependenceHighGrayLevelEmphasis"  9.000000 ##
#    10.  "LargeDependenceLowGrayLevelEmphasis"  4.000000 #
#    11.                    "GrayLevelVariance"  1.000000
#    12.              "LargeDependenceEmphasis"  1.000000
#
# Variable Importance: NUM_NODES:
#     1. "LargeDependenceHighGrayLevelEmphasis" 699.000000 ################
#     2.                    "DependenceEntropy" 648.000000 ##############
#     3.              "SmallDependenceEmphasis" 582.000000 ############
#     4.  "SmallDependenceLowGrayLevelEmphasis" 516.000000 ##########
#     5. "SmallDependenceHighGrayLevelEmphasis" 513.000000 ##########
#     6.               "GrayLevelNonUniformity" 474.000000 #########
#     7.                    "GrayLevelVariance" 441.000000 ########
#     8.                "HighGrayLevelEmphasis" 432.000000 ########
#     9.                   "DependenceVariance" 354.000000 ######
#    10.  "LargeDependenceLowGrayLevelEmphasis" 323.000000 #####
#    11.                 "LowGrayLevelEmphasis" 311.000000 #####
#    12.              "LargeDependenceEmphasis" 208.000000 ##
#    13.    "DependenceNonUniformityNormalized" 122.000000
#    14.              "DependenceNonUniformity" 119.000000
#
# Variable Importance: SUM_SCORE:
#     1.                 "LowGrayLevelEmphasis" 64178.636530 ################
#     2.                    "DependenceEntropy" 58885.419847 ##############
#     3. "LargeDependenceHighGrayLevelEmphasis" 37562.253131 #########
#     4. "SmallDependenceHighGrayLevelEmphasis" 30886.632554 #######
#     5.                "HighGrayLevelEmphasis" 28611.307157 #######
#     6.  "SmallDependenceLowGrayLevelEmphasis" 17921.561440 ####
#     7.              "SmallDependenceEmphasis" 7978.657883 #
#     8.               "GrayLevelNonUniformity" 7147.484089 #
#     9.                    "GrayLevelVariance" 4033.915527
#    10.                   "DependenceVariance" 3131.675575
#    11.  "LargeDependenceLowGrayLevelEmphasis" 2418.900447
#    12.              "LargeDependenceEmphasis" 1004.876616
#    13.    "DependenceNonUniformityNormalized" 620.934734
#    14.              "DependenceNonUniformity" 599.721100
#
#
#
# Loss: BINOMIAL_LOG_LIKELIHOOD
# Validation loss value: 0.586994
# Number of trees per iteration: 1
# Node format: NOT_SET
# Number of trees: 207
# Total number of nodes: 11691
#
# Number of nodes by tree:
# Count: 207 Average: 56.4783 StdDev: 6.91133
# Min: 29 Max: 63 Ignored: 0
# ----------------------------------------------
# [ 29, 30)  1   0.48%   0.48%
# [ 30, 32)  2   0.97%   1.45%
# [ 32, 34)  1   0.48%   1.93%
# [ 34, 36)  0   0.00%   1.93%
# [ 36, 37)  0   0.00%   1.93%
# [ 37, 39)  0   0.00%   1.93%
# [ 39, 41)  0   0.00%   1.93%
# [ 41, 43)  3   1.45%   3.38% #
# [ 43, 44)  1   0.48%   3.86%
# [ 44, 46)  5   2.42%   6.28% #
# [ 46, 48) 16   7.73%  14.01% ###
# [ 48, 50) 14   6.76%  20.77% ##
# [ 50, 51)  0   0.00%  20.77%
# [ 51, 53)  4   1.93%  22.71% #
# [ 53, 55) 13   6.28%  28.99% ##
# [ 55, 57) 18   8.70%  37.68% ###
# [ 57, 58) 23  11.11%  48.79% ####
# [ 58, 60) 19   9.18%  57.97% ###
# [ 60, 62) 29  14.01%  71.98% #####
# [ 62, 63] 58  28.02% 100.00% ##########
#
# Depth by leafs:
# Count: 5949 Average: 4.92032 StdDev: 0.360756
# Min: 1 Max: 5 Ignored: 0
# ----------------------------------------------
# [ 1, 2)    1   0.02%   0.02%
# [ 2, 3)   27   0.45%   0.47%
# [ 3, 4)   82   1.38%   1.85%
# [ 4, 5)  225   3.78%   5.63%
# [ 5, 5] 5614  94.37% 100.00% ##########
#
# Number of training obs by leaf:
# Count: 5949 Average: 9875.14 StdDev: 32385.7
# Min: 5 Max: 279048 Ignored: 0
# ----------------------------------------------
# [      5,  13957) 5193  87.29%  87.29% ##########
# [  13957,  27909)  294   4.94%  92.23% #
# [  27909,  41861)  129   2.17%  94.40%
# [  41861,  55813)   71   1.19%  95.60%
# [  55813,  69766)   51   0.86%  96.45%
# [  69766,  83718)   24   0.40%  96.86%
# [  83718,  97670)   20   0.34%  97.19%
# [  97670, 111622)   17   0.29%  97.48%
# [ 111622, 125574)   12   0.20%  97.68%
# [ 125574, 139527)   17   0.29%  97.97%
# [ 139527, 153479)   10   0.17%  98.13%
# [ 153479, 167431)   18   0.30%  98.44%
# [ 167431, 181383)   19   0.32%  98.76%
# [ 181383, 195335)    8   0.13%  98.89%
# [ 195335, 209288)   13   0.22%  99.11%
# [ 209288, 223240)   14   0.24%  99.34%
# [ 223240, 237192)   12   0.20%  99.55%
# [ 237192, 251144)    9   0.15%  99.70%
# [ 251144, 265096)   11   0.18%  99.88%
# [ 265096, 279048]    7   0.12% 100.00%
#
# Attribute in nodes:
# 	699 : LargeDependenceHighGrayLevelEmphasis [NUMERICAL]
# 	648 : DependenceEntropy [NUMERICAL]
# 	582 : SmallDependenceEmphasis [NUMERICAL]
# 	516 : SmallDependenceLowGrayLevelEmphasis [NUMERICAL]
# 	513 : SmallDependenceHighGrayLevelEmphasis [NUMERICAL]
# 	474 : GrayLevelNonUniformity [NUMERICAL]
# 	441 : GrayLevelVariance [NUMERICAL]
# 	432 : HighGrayLevelEmphasis [NUMERICAL]
# 	354 : DependenceVariance [NUMERICAL]
# 	323 : LargeDependenceLowGrayLevelEmphasis [NUMERICAL]
# 	311 : LowGrayLevelEmphasis [NUMERICAL]
# 	208 : LargeDependenceEmphasis [NUMERICAL]
# 	122 : DependenceNonUniformityNormalized [NUMERICAL]
# 	119 : DependenceNonUniformity [NUMERICAL]
#
# Attribute in nodes with depth <= 0:
# 	49 : LargeDependenceHighGrayLevelEmphasis [NUMERICAL]
# 	32 : GrayLevelNonUniformity [NUMERICAL]
# 	24 : SmallDependenceLowGrayLevelEmphasis [NUMERICAL]
# 	24 : DependenceEntropy [NUMERICAL]
# 	21 : DependenceVariance [NUMERICAL]
# 	19 : LowGrayLevelEmphasis [NUMERICAL]
# 	13 : HighGrayLevelEmphasis [NUMERICAL]
# 	10 : SmallDependenceEmphasis [NUMERICAL]
# 	9 : SmallDependenceHighGrayLevelEmphasis [NUMERICAL]
# 	4 : LargeDependenceLowGrayLevelEmphasis [NUMERICAL]
# 	1 : LargeDependenceEmphasis [NUMERICAL]
# 	1 : GrayLevelVariance [NUMERICAL]
#
# Attribute in nodes with depth <= 1:
# 	107 : LargeDependenceHighGrayLevelEmphasis [NUMERICAL]
# 	83 : SmallDependenceEmphasis [NUMERICAL]
# 	78 : DependenceEntropy [NUMERICAL]
# 	74 : SmallDependenceLowGrayLevelEmphasis [NUMERICAL]
# 	57 : GrayLevelNonUniformity [NUMERICAL]
# 	47 : DependenceVariance [NUMERICAL]
# 	41 : SmallDependenceHighGrayLevelEmphasis [NUMERICAL]
# 	38 : LowGrayLevelEmphasis [NUMERICAL]
# 	36 : HighGrayLevelEmphasis [NUMERICAL]
# 	29 : GrayLevelVariance [NUMERICAL]
# 	17 : LargeDependenceLowGrayLevelEmphasis [NUMERICAL]
# 	11 : LargeDependenceEmphasis [NUMERICAL]
# 	1 : DependenceNonUniformityNormalized [NUMERICAL]
# 	1 : DependenceNonUniformity [NUMERICAL]
#
# Attribute in nodes with depth <= 2:
# 	199 : LargeDependenceHighGrayLevelEmphasis [NUMERICAL]
# 	173 : SmallDependenceEmphasis [NUMERICAL]
# 	150 : DependenceEntropy [NUMERICAL]
# 	126 : SmallDependenceHighGrayLevelEmphasis [NUMERICAL]
# 	120 : SmallDependenceLowGrayLevelEmphasis [NUMERICAL]
# 	115 : DependenceVariance [NUMERICAL]
# 	106 : HighGrayLevelEmphasis [NUMERICAL]
# 	105 : GrayLevelNonUniformity [NUMERICAL]
# 	91 : GrayLevelVariance [NUMERICAL]
# 	84 : LowGrayLevelEmphasis [NUMERICAL]
# 	66 : LargeDependenceLowGrayLevelEmphasis [NUMERICAL]
# 	44 : LargeDependenceEmphasis [NUMERICAL]
# 	20 : DependenceNonUniformityNormalized [NUMERICAL]
# 	20 : DependenceNonUniformity [NUMERICAL]
#
# Attribute in nodes with depth <= 3:
# 	360 : LargeDependenceHighGrayLevelEmphasis [NUMERICAL]
# 	342 : DependenceEntropy [NUMERICAL]
# 	313 : SmallDependenceEmphasis [NUMERICAL]
# 	259 : SmallDependenceHighGrayLevelEmphasis [NUMERICAL]
# 	256 : SmallDependenceLowGrayLevelEmphasis [NUMERICAL]
# 	227 : GrayLevelNonUniformity [NUMERICAL]
# 	226 : HighGrayLevelEmphasis [NUMERICAL]
# 	206 : GrayLevelVariance [NUMERICAL]
# 	201 : DependenceVariance [NUMERICAL]
# 	160 : LowGrayLevelEmphasis [NUMERICAL]
# 	158 : LargeDependenceLowGrayLevelEmphasis [NUMERICAL]
# 	97 : LargeDependenceEmphasis [NUMERICAL]
# 	67 : DependenceNonUniformity [NUMERICAL]
# 	63 : DependenceNonUniformityNormalized [NUMERICAL]
#
# Attribute in nodes with depth <= 5:
# 	699 : LargeDependenceHighGrayLevelEmphasis [NUMERICAL]
# 	648 : DependenceEntropy [NUMERICAL]
# 	582 : SmallDependenceEmphasis [NUMERICAL]
# 	516 : SmallDependenceLowGrayLevelEmphasis [NUMERICAL]
# 	513 : SmallDependenceHighGrayLevelEmphasis [NUMERICAL]
# 	474 : GrayLevelNonUniformity [NUMERICAL]
# 	441 : GrayLevelVariance [NUMERICAL]
# 	432 : HighGrayLevelEmphasis [NUMERICAL]
# 	354 : DependenceVariance [NUMERICAL]
# 	323 : LargeDependenceLowGrayLevelEmphasis [NUMERICAL]
# 	311 : LowGrayLevelEmphasis [NUMERICAL]
# 	208 : LargeDependenceEmphasis [NUMERICAL]
# 	122 : DependenceNonUniformityNormalized [NUMERICAL]
# 	119 : DependenceNonUniformity [NUMERICAL]
#
# Condition type in nodes:
# 	5742 : HigherCondition
# Condition type in nodes with depth <= 0:
# 	207 : HigherCondition
# Condition type in nodes with depth <= 1:
# 	620 : HigherCondition
# Condition type in nodes with depth <= 2:
# 	1419 : HigherCondition
# Condition type in nodes with depth <= 3:
# 	2935 : HigherCondition
# Condition type in nodes with depth <= 5:
# 	5742 : HigherCondition
#
# Training logs:
# Number of iteration to final model: 207
# 	Iter:1 train-loss:1.284483 valid-loss:1.287301  train-accuracy:0.832920 valid-accuracy:0.820530
# 	Iter:2 train-loss:1.200567 valid-loss:1.205712  train-accuracy:0.842076 valid-accuracy:0.833184
# 	Iter:3 train-loss:1.129826 valid-loss:1.137022  train-accuracy:0.845016 valid-accuracy:0.836286
# 	Iter:4 train-loss:1.069514 valid-loss:1.078719  train-accuracy:0.848631 valid-accuracy:0.840038
# 	Iter:5 train-loss:1.017040 valid-loss:1.027246  train-accuracy:0.852706 valid-accuracy:0.845377
# 	Iter:6 train-loss:0.971126 valid-loss:0.982105  train-accuracy:0.856608 valid-accuracy:0.848714
# 	Iter:16 train-loss:0.727547 valid-loss:0.747125  train-accuracy:0.867475 valid-accuracy:0.857380
# 	Iter:26 train-loss:0.642085 valid-loss:0.667350  train-accuracy:0.872845 valid-accuracy:0.863757
# 	Iter:36 train-loss:0.605979 valid-loss:0.635631  train-accuracy:0.875696 valid-accuracy:0.867605
# 	Iter:46 train-loss:0.587149 valid-loss:0.620734  train-accuracy:0.877834 valid-accuracy:0.869473
# 	Iter:56 train-loss:0.574385 valid-loss:0.612265  train-accuracy:0.880278 valid-accuracy:0.870319
# 	Iter:66 train-loss:0.563523 valid-loss:0.606309  train-accuracy:0.882070 valid-accuracy:0.870134
# 	Iter:76 train-loss:0.554823 valid-loss:0.602590  train-accuracy:0.883593 valid-accuracy:0.872120
# 	Iter:86 train-loss:0.547426 valid-loss:0.599835  train-accuracy:0.884996 valid-accuracy:0.871654
# 	Iter:96 train-loss:0.541595 valid-loss:0.598239  train-accuracy:0.885874 valid-accuracy:0.872063
# 	Iter:106 train-loss:0.536115 valid-loss:0.596339  train-accuracy:0.887090 valid-accuracy:0.872927
# 	Iter:116 train-loss:0.530415 valid-loss:0.593506  train-accuracy:0.888419 valid-accuracy:0.872557
# 	Iter:126 train-loss:0.525531 valid-loss:0.592166  train-accuracy:0.889538 valid-accuracy:0.872770
# 	Iter:136 train-loss:0.519823 valid-loss:0.591052  train-accuracy:0.890802 valid-accuracy:0.872815
# 	Iter:146 train-loss:0.515629 valid-loss:0.590557  train-accuracy:0.891815 valid-accuracy:0.872916
# 	Iter:156 train-loss:0.511105 valid-loss:0.589416  train-accuracy:0.892761 valid-accuracy:0.873061
# 	Iter:166 train-loss:0.507064 valid-loss:0.588231  train-accuracy:0.893502 valid-accuracy:0.873729
# 	Iter:176 train-loss:0.503037 valid-loss:0.587833  train-accuracy:0.894691 valid-accuracy:0.874133
# 	Iter:186 train-loss:0.499660 valid-loss:0.587427  train-accuracy:0.895514 valid-accuracy:0.874795
# 	Iter:196 train-loss:0.496362 valid-loss:0.587331  train-accuracy:0.896650 valid-accuracy:0.874553
# 	Iter:206 train-loss:0.493220 valid-loss:0.587041  train-accuracy:0.897387 valid-accuracy:0.873976
# 	Iter:216 train-loss:0.489992 valid-loss:0.587509  train-accuracy:0.898391 valid-accuracy:0.874144
# 	Iter:226 train-loss:0.487434 valid-loss:0.587163  train-accuracy:0.898898 valid-accuracy:0.873998
# 	Iter:236 train-loss:0.483988 valid-loss:0.587302  train-accuracy:0.899614 valid-accuracy:0.875193

# %%
# Model features
model.make_inspector().features()
# Out:
# ["DependenceEntropy" (1; #0),
#  "DependenceNonUniformity" (1; #1),
#  "DependenceNonUniformityNormalized" (1; #2),
#  "DependenceVariance" (1; #3),
#  "GrayLevelNonUniformity" (1; #4),
#  "GrayLevelVariance" (1; #5),
#  "HighGrayLevelEmphasis" (1; #6),
#  "LargeDependenceEmphasis" (1; #7),
#  "LargeDependenceHighGrayLevelEmphasis" (1; #8),
#  "LargeDependenceLowGrayLevelEmphasis" (1; #9),
#  "LowGrayLevelEmphasis" (1; #10),
#  "SmallDependenceEmphasis" (1; #11),
#  "SmallDependenceHighGrayLevelEmphasis" (1; #12),
#  "SmallDependenceLowGrayLevelEmphasis" (1; #13)]

# %%
# Feature importance
model.make_inspector().variable_importances()
# Out:
# {'INV_MEAN_MIN_DEPTH': [("LargeDependenceHighGrayLevelEmphasis" (1; #8),
#    0.25039602950192297),
#   ("DependenceEntropy" (1; #0), 0.2284074267153747),
#   ("SmallDependenceEmphasis" (1; #11), 0.2191689304988202),
#   ("SmallDependenceLowGrayLevelEmphasis" (1; #13), 0.21576493127558152),
#   ("GrayLevelNonUniformity" (1; #4), 0.21536298167098453),
#   ("SmallDependenceHighGrayLevelEmphasis" (1; #12), 0.2033738248980561),
#   ("DependenceVariance" (1; #3), 0.19927588216922104),
#   ("HighGrayLevelEmphasis" (1; #6), 0.19922473346682243),
#   ("LowGrayLevelEmphasis" (1; #10), 0.1956355722226874),
#   ("GrayLevelVariance" (1; #5), 0.19066266353105263),
#   ("LargeDependenceLowGrayLevelEmphasis" (1; #9), 0.18524117881829993),
#   ("LargeDependenceEmphasis" (1; #7), 0.17842589838629158),
#   ("DependenceNonUniformity" (1; #1), 0.17372284258055762),
#   ("DependenceNonUniformityNormalized" (1; #2), 0.1734388525203591)],
#  'NUM_AS_ROOT': [("LargeDependenceHighGrayLevelEmphasis" (1; #8), 49.0),
#   ("GrayLevelNonUniformity" (1; #4), 32.0),
#   ("DependenceEntropy" (1; #0), 24.0),
#   ("SmallDependenceLowGrayLevelEmphasis" (1; #13), 24.0),
#   ("DependenceVariance" (1; #3), 21.0),
#   ("LowGrayLevelEmphasis" (1; #10), 19.0),
#   ("HighGrayLevelEmphasis" (1; #6), 13.0),
#   ("SmallDependenceEmphasis" (1; #11), 10.0),
#   ("SmallDependenceHighGrayLevelEmphasis" (1; #12), 9.0),
#   ("LargeDependenceLowGrayLevelEmphasis" (1; #9), 4.0),
#   ("GrayLevelVariance" (1; #5), 1.0),
#   ("LargeDependenceEmphasis" (1; #7), 1.0)],
#  'SUM_SCORE': [("LowGrayLevelEmphasis" (1; #10), 64178.63653043911),
#   ("DependenceEntropy" (1; #0), 58885.41984733655),
#   ("LargeDependenceHighGrayLevelEmphasis" (1; #8), 37562.25313110602),
#   ("SmallDependenceHighGrayLevelEmphasis" (1; #12), 30886.63255370208),
#   ("HighGrayLevelEmphasis" (1; #6), 28611.307157205738),
#   ("SmallDependenceLowGrayLevelEmphasis" (1; #13), 17921.561439770318),
#   ("SmallDependenceEmphasis" (1; #11), 7978.657882525597),
#   ("GrayLevelNonUniformity" (1; #4), 7147.484089355905),
#   ("GrayLevelVariance" (1; #5), 4033.915526527002),
#   ("DependenceVariance" (1; #3), 3131.6755750609336),
#   ("LargeDependenceLowGrayLevelEmphasis" (1; #9), 2418.9004469745714),
#   ("LargeDependenceEmphasis" (1; #7), 1004.8766156700424),
#   ("DependenceNonUniformityNormalized" (1; #2), 620.9347344480462),
#   ("DependenceNonUniformity" (1; #1), 599.7211001342998)],
#  'NUM_NODES': [("LargeDependenceHighGrayLevelEmphasis" (1; #8), 699.0),
#   ("DependenceEntropy" (1; #0), 648.0),
#   ("SmallDependenceEmphasis" (1; #11), 582.0),
#   ("SmallDependenceLowGrayLevelEmphasis" (1; #13), 516.0),
#   ("SmallDependenceHighGrayLevelEmphasis" (1; #12), 513.0),
#   ("GrayLevelNonUniformity" (1; #4), 474.0),
#   ("GrayLevelVariance" (1; #5), 441.0),
#   ("HighGrayLevelEmphasis" (1; #6), 432.0),
#   ("DependenceVariance" (1; #3), 354.0),
#   ("LargeDependenceLowGrayLevelEmphasis" (1; #9), 323.0),
#   ("LowGrayLevelEmphasis" (1; #10), 311.0),
#   ("LargeDependenceEmphasis" (1; #7), 208.0),
#   ("DependenceNonUniformityNormalized" (1; #2), 122.0),
#   ("DependenceNonUniformity" (1; #1), 119.0)]}

# %%
# Model self evaluation
model.make_inspector().evaluation()
# Out:
# Evaluation(num_examples=None, accuracy=0.873941957950592, loss=0.5869935750961304, rmse=None, ndcg=None, aucs=None, auuc=None, qini=None)

# %%
logs = model.make_inspector().training_logs()

plt.figure(figsize=(12, 4))
plt.subplot(1, 2, 1)
plt.plot([log.num_trees for log in logs], [log.evaluation.accuracy for log in logs])
plt.xlabel("Number of trees")
plt.ylabel("Accuracy (out-of-bag)")
plt.subplot(1, 2, 2)
plt.plot([log.num_trees for log in logs], [log.evaluation.loss for log in logs])
plt.xlabel("Number of trees")
plt.ylabel("Logloss (out-of-bag)")
plt.show()

# %% [markdown]
# Calculate the score of our hold-out validation dataset

# %%
predictions = model.predict(val_ds)
y_true      = validation_data["label"]

from sklearn.metrics import roc_auc_score
ROC_AUC = roc_auc_score(y_true, predictions)
print("The ROC AUC score is %.5f" % ROC_AUC )
# Out:
#  1/46 [..............................] - ETA: 2s
# 14/46 [========>.....................] - ETA: 0s
# 29/46 [=================>............] - ETA: 0s
# 42/46 [==========================>...] - ETA: 0s
# 46/46 [==============================] - 0s 4ms/step
# The ROC AUC score is 0.95513

# %%
# Compute binary classification metrics with sklearn
import numpy as np
from sklearn.metrics import (
    accuracy_score,
    precision_score,
    recall_score,
    f1_score,
    roc_auc_score,
    average_precision_score,
    confusion_matrix,
    classification_report,
    matthews_corrcoef,
    log_loss,
    brier_score_loss,
)

# Get predictions (probabilities or class labels)
preds = model.predict(test_ds)
# If model outputs probabilities, convert to labels by threshold 0.5
if preds.ndim == 2:
    # For TFDF classification, preds may be class probabilities with shape (N, 2)
    if preds.shape[1] == 2:
        pos_probs = preds[:, 1]
    else:
        # If single-probability column (positive class)
        pos_probs = preds[:, -1]
    y_pred = (pos_probs >= 0.5).astype(int)
else:
    # Already class labels
    y_pred = preds.astype(int)
    pos_probs = None

# Ground truth labels (must be 0/1 integers)
y_true = test_data["label"].astype(int).to_numpy()

# Core metrics
metrics = {}
metrics["accuracy"] = accuracy_score(y_true, y_pred)
metrics["precision"] = precision_score(y_true, y_pred, zero_division=0)
metrics["recall"] = recall_score(y_true, y_pred, zero_division=0)
metrics["f1"] = f1_score(y_true, y_pred, zero_division=0)
metrics["mcc"] = matthews_corrcoef(y_true, y_pred)

# Probabilistic metrics (only if we have probabilities)
if pos_probs is not None:
    metrics["roc_auc"] = roc_auc_score(y_true, pos_probs)
    metrics["pr_auc"] = average_precision_score(y_true, pos_probs)
    metrics["log_loss"] = log_loss(y_true, pos_probs, labels=[0,1])
    metrics["brier_score"] = brier_score_loss(y_true, pos_probs)

# Confusion matrix and detailed report
cm = confusion_matrix(y_true, y_pred, labels=[0,1])
report = classification_report(y_true, y_pred, digits=4)

print("Sklearn binary metrics:")
for k, v in metrics.items():
    print(f"{k}: {v:.4f}")
print("\nConfusion matrix:\n", cm)
print("\nClassification report:\n", report)
# Out:
#  1/91 [..............................] - ETA: 5s
# 14/91 [===>..........................] - ETA: 0s
# 28/91 [========>.....................] - ETA: 0s
# 42/91 [============>.................] - ETA: 0s
# 56/91 [=================>............] - ETA: 0s
# 71/91 [======================>.......] - ETA: 0s
# 86/91 [===========================>..] - ETA: 0s
# 91/91 [==============================] - 0s 4ms/step
# Sklearn binary metrics:
# accuracy: 0.8900
# precision: 0.3488
# recall: 0.8673
# f1: 0.4975
# mcc: 0.5072
# roc_auc: 0.9520
# pr_auc: 0.6984
# log_loss: 0.2651
# brier_score: 0.0808
#
# Confusion matrix:
#  [[75309  9162]
#  [  751  4908]]
#
# Classification report:
#                precision    recall  f1-score   support
#
#            0     0.9901    0.8915    0.9382     84471
#            1     0.3488    0.8673    0.4975      5659
#
#     accuracy                         0.8900     90130
#    macro avg     0.6695    0.8794    0.7179     90130
# weighted avg     0.9499    0.8900    0.9106     90130
