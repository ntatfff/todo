# %%
# Import packages and modules
import numpy  as np
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow_decision_forests as tfdf

from sklearn.model_selection import train_test_split
# Out:
# 2026-08-15 05:19:53.835304: I tensorflow/core/util/port.cc:113] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2026-08-15 05:19:54.213850: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2026-08-15 05:19:58.927527: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
# Check the version of TensorFlow Decision Forests
print("Found TensorFlow Decision Forests v" + tfdf.__version__)
# Out:
# Found TensorFlow Decision Forests v1.9.1

# %%
datasetPath = 'dataset/firstorder/kernel5/dataset.csv'

# %%
# Parameters
datasetPath = "dataset/firstorder/kernel6/1.dataset.csv"

# %%
# train/validation/test = 70/10/20
dataset = pd.read_csv(datasetPath)

train_data, temp_data = train_test_split(dataset, test_size=0.3, random_state=42)
validation_data, test_data = train_test_split(temp_data, test_size=2/3, random_state=42)

# %%
from sklearn.utils.class_weight import compute_class_weight

# tinh class weight tren tap train
classes = np.array([0, 1])
weights = compute_class_weight(class_weight="balanced", classes=classes, y=train_data["label"])
class_weight = {0: weights[0], 1: weights[1]}

# gan sample_weight cho tung dong
train_data["sample_weight"] = train_data["label"].map(class_weight)
validation_data["sample_weight"] = validation_data["label"].map(class_weight)
test_data["sample_weight"] = test_data["label"].map(class_weight)

# Convert the dataset into a TensorFlow dataset.
train_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    train_data, label="label", weight="sample_weight"
)         
val_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    validation_data, label="label", weight="sample_weight"
)
test_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    test_data, label="label", weight="sample_weight"
)
# Out:
# 2026-08-15 05:20:12.609354: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:984] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2026-08-15 05:20:12.610939: W tensorflow/core/common_runtime/gpu/gpu_device.cc:2251] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...

# %%
import keras

# %%
# %%time

# Train a Random Forest model.
model = tfdf.keras.RandomForestModel()

# Add evaluation metrics
model.compile(
    metrics=["accuracy"]
)
model.fit(x=train_ds)

# # Train a Gradient Boosted Trees model.
# model = tfdf.keras.GradientBoostedTreesModel(num_trees=1500)
# model.fit(train_ds)
# Out:
# Use /tmp/tmp3rklgcxr as temporary training directory
# Reading training dataset...
# Training dataset read in 0:00:02.633395. Found 507 examples.
# Training model...
# Model trained in 0:00:00.043059
# Compiling model...
# [INFO 26-08-15 05:20:15.4643 UTC kernel.cc:1233] Loading model from path /tmp/tmp3rklgcxr/model/ with prefix ff91b9d1ec384d87
# [INFO 26-08-15 05:20:15.4690 UTC decision_forest.cc:734] Model loaded with 300 root(s), 3002 node(s), and 18 input feature(s).
# [INFO 26-08-15 05:20:15.4691 UTC abstract_model.cc:1362] Engine "RandomForestOptPred" built
# [INFO 26-08-15 05:20:15.4691 UTC kernel.cc:1061] Use fast generic engine
# Model compiled.
# CPU times: user 5.5 s, sys: 113 ms, total: 5.61 s
# Wall time: 5.92 s

# %%
# Evaluate the model
evaluate = model.evaluate(val_ds, return_dict=True)
print()

for name, value in evaluate.items():
    print(f"{name}: {value:.4f}")
# Out:
# WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 1/1 [==============================] - ETA: 0s - loss: 0.0000e+00 - accuracy: 0.9861
# 1/1 [==============================] - 3s 3s/step - loss: 0.0000e+00 - accuracy: 0.9861
# loss: 0.0000
# accuracy: 0.9861

# %%
# Model Summary
model.summary()
# Out:
# Model: "random_forest_model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
# =================================================================
# Total params: 1 (1.00 Byte)
# Trainable params: 0 (0.00 Byte)
# Non-trainable params: 1 (1.00 Byte)
# _________________________________________________________________
# Type: "RANDOM_FOREST"
# Task: CLASSIFICATION
# Label: "__LABEL"
#
# Input Features (18):
# 	10Percentile
# 	90Percentile
# 	Energy
# 	Entropy
# 	InterquartileRange
# 	Kurtosis
# 	Maximum
# 	Mean
# 	MeanAbsoluteDeviation
# 	Median
# 	Minimum
# 	Range
# 	RobustMeanAbsoluteDeviation
# 	RootMeanSquared
# 	Skewness
# 	TotalEnergy
# 	Uniformity
# 	Variance
#
# Trained with weights
#
# Variable Importance: INV_MEAN_MIN_DEPTH:
#     1.                "90Percentile"  0.384562 ################
#     2.                     "Maximum"  0.350655 ###########
#     3.                 "TotalEnergy"  0.298087 ####
#     4.             "RootMeanSquared"  0.297594 ####
#     5.                     "Minimum"  0.294352 ###
#     6.                      "Energy"  0.291886 ###
#     7.                      "Median"  0.289633 ###
#     8.                    "Kurtosis"  0.283515 ##
#     9.                  "Uniformity"  0.280206 ##
#    10.                     "Entropy"  0.279683 ##
#    11.                        "Mean"  0.276852 #
#    12.                    "Skewness"  0.274978 #
#    13.                       "Range"  0.271370
#    14. "RobustMeanAbsoluteDeviation"  0.269780
#    15.          "InterquartileRange"  0.267035
#    16.                "10Percentile"  0.265377
#    17.                    "Variance"  0.265282
#    18.       "MeanAbsoluteDeviation"  0.264499
#
# Variable Importance: NUM_AS_ROOT:
#     1.                "90Percentile" 93.000000 ################
#     2.                     "Maximum" 73.000000 ############
#     3.             "RootMeanSquared" 33.000000 #####
#     4.                 "TotalEnergy" 33.000000 #####
#     5.                      "Energy" 30.000000 #####
#     6.                      "Median" 17.000000 ##
#     7.                     "Entropy"  7.000000 #
#     8.                        "Mean"  7.000000 #
#     9.                  "Uniformity"  6.000000
#    10. "RobustMeanAbsoluteDeviation"  1.000000
#
# Variable Importance: NUM_NODES:
#     1.                "90Percentile" 189.000000 ################
#     2.                     "Maximum" 137.000000 ###########
#     3.                     "Minimum" 115.000000 ########
#     4.                      "Median" 108.000000 ########
#     5.                  "Uniformity" 98.000000 #######
#     6.                 "TotalEnergy" 89.000000 ######
#     7.             "RootMeanSquared" 80.000000 #####
#     8.                     "Entropy" 79.000000 #####
#     9.                      "Energy" 71.000000 ####
#    10.                       "Range" 69.000000 ####
#    11.                    "Kurtosis" 64.000000 ####
#    12.                        "Mean" 55.000000 ###
#    13.                    "Skewness" 52.000000 ##
#    14. "RobustMeanAbsoluteDeviation" 39.000000 #
#    15.          "InterquartileRange" 31.000000
#    16.                "10Percentile" 30.000000
#    17.                    "Variance" 23.000000
#    18.       "MeanAbsoluteDeviation" 22.000000
#
# Variable Importance: SUM_SCORE:
#     1.                "90Percentile" 32042.501503 ################
#     2.                     "Maximum" 23949.871999 ###########
#     3.             "RootMeanSquared" 9205.893478 ####
#     4.                 "TotalEnergy" 9030.805927 ####
#     5.                      "Energy" 8296.901568 ####
#     6.                      "Median" 4637.511043 ##
#     7.                     "Entropy" 3679.876412 #
#     8.                  "Uniformity" 3624.982127 #
#     9.                        "Mean" 1912.507622
#    10.                     "Minimum" 1698.361239
#    11.                    "Kurtosis" 1065.303842
#    12.                       "Range" 872.716659
#    13. "RobustMeanAbsoluteDeviation" 519.521500
#    14.                    "Skewness" 488.849939
#    15.          "InterquartileRange" 386.407697
#    16.       "MeanAbsoluteDeviation" 375.408619
#    17.                    "Variance" 278.139956
#    18.                "10Percentile" 208.242389
#
#
#
# Winner takes all: true
# Out-of-bag evaluation: accuracy:0.962474 logloss:0.131771
# Number of trees: 300
# Total number of nodes: 3002
#
# Number of nodes by tree:
# Count: 300 Average: 10.0067 StdDev: 2.23606
# Min: 3 Max: 15 Ignored: 0
# ----------------------------------------------
# [  3,  4)   1   0.33%   0.33%
# [  4,  5)   0   0.00%   0.33%
# [  5,  6)  13   4.33%   4.67% #
# [  6,  7)   0   0.00%   4.67%
# [  7,  8)  38  12.67%  17.33% ####
# [  8,  9)   0   0.00%  17.33%
# [  9, 10)  90  30.00%  47.33% #########
# [ 10, 11)   0   0.00%  47.33%
# [ 11, 12) 105  35.00%  82.33% ##########
# [ 12, 13)   0   0.00%  82.33%
# [ 13, 14)  46  15.33%  97.67% ####
# [ 14, 15)   0   0.00%  97.67%
# [ 15, 15]   7   2.33% 100.00% #
#
# Depth by leafs:
# Count: 1651 Average: 2.91157 StdDev: 1.20394
# Min: 1 Max: 6 Ignored: 0
# ----------------------------------------------
# [ 1, 2) 200  12.11%  12.11% ####
# [ 2, 3) 441  26.71%  38.82% ########
# [ 3, 4) 524  31.74%  70.56% ##########
# [ 4, 5) 303  18.35%  88.92% ######
# [ 5, 6) 157   9.51%  98.43% ###
# [ 6, 6]  26   1.57% 100.00%
#
# Number of training obs by leaf:
# Count: 1651 Average: 92.126 StdDev: 169.629
# Min: 5 Max: 489 Ignored: 0
# ----------------------------------------------
# [   5,  29) 1277  77.35%  77.35% ##########
# [  29,  53)   61   3.69%  81.04%
# [  53,  77)    6   0.36%  81.41%
# [  77, 102)    2   0.12%  81.53%
# [ 102, 126)    2   0.12%  81.65%
# [ 126, 150)    2   0.12%  81.77%
# [ 150, 174)    0   0.00%  81.77%
# [ 174, 199)    1   0.06%  81.83%
# [ 199, 223)    0   0.00%  81.83%
# [ 223, 247)    0   0.00%  81.83%
# [ 247, 271)    1   0.06%  81.89%
# [ 271, 296)    0   0.00%  81.89%
# [ 296, 320)    0   0.00%  81.89%
# [ 320, 344)    2   0.12%  82.01%
# [ 344, 368)    3   0.18%  82.19%
# [ 368, 393)    2   0.12%  82.31%
# [ 393, 417)   11   0.67%  82.98%
# [ 417, 441)   25   1.51%  84.49%
# [ 441, 465)  201  12.17%  96.67% ##
# [ 465, 489]   55   3.33% 100.00%
#
# Attribute in nodes:
# 	189 : 90Percentile [NUMERICAL]
# 	137 : Maximum [NUMERICAL]
# 	115 : Minimum [NUMERICAL]
# 	108 : Median [NUMERICAL]
# 	98 : Uniformity [NUMERICAL]
# 	89 : TotalEnergy [NUMERICAL]
# 	80 : RootMeanSquared [NUMERICAL]
# 	79 : Entropy [NUMERICAL]
# 	71 : Energy [NUMERICAL]
# 	69 : Range [NUMERICAL]
# 	64 : Kurtosis [NUMERICAL]
# 	55 : Mean [NUMERICAL]
# 	52 : Skewness [NUMERICAL]
# 	39 : RobustMeanAbsoluteDeviation [NUMERICAL]
# 	31 : InterquartileRange [NUMERICAL]
# 	30 : 10Percentile [NUMERICAL]
# 	23 : Variance [NUMERICAL]
# 	22 : MeanAbsoluteDeviation [NUMERICAL]
#
# Attribute in nodes with depth <= 0:
# 	93 : 90Percentile [NUMERICAL]
# 	73 : Maximum [NUMERICAL]
# 	33 : TotalEnergy [NUMERICAL]
# 	33 : RootMeanSquared [NUMERICAL]
# 	30 : Energy [NUMERICAL]
# 	17 : Median [NUMERICAL]
# 	7 : Mean [NUMERICAL]
# 	7 : Entropy [NUMERICAL]
# 	6 : Uniformity [NUMERICAL]
# 	1 : RobustMeanAbsoluteDeviation [NUMERICAL]
#
# Attribute in nodes with depth <= 1:
# 	155 : 90Percentile [NUMERICAL]
# 	109 : Maximum [NUMERICAL]
# 	58 : TotalEnergy [NUMERICAL]
# 	54 : RootMeanSquared [NUMERICAL]
# 	47 : Energy [NUMERICAL]
# 	43 : Minimum [NUMERICAL]
# 	43 : Median [NUMERICAL]
# 	36 : Entropy [NUMERICAL]
# 	34 : Uniformity [NUMERICAL]
# 	31 : Kurtosis [NUMERICAL]
# 	30 : Mean [NUMERICAL]
# 	21 : Range [NUMERICAL]
# 	16 : Skewness [NUMERICAL]
# 	6 : Variance [NUMERICAL]
# 	6 : RobustMeanAbsoluteDeviation [NUMERICAL]
# 	6 : InterquartileRange [NUMERICAL]
# 	4 : MeanAbsoluteDeviation [NUMERICAL]
# 	1 : 10Percentile [NUMERICAL]
#
# Attribute in nodes with depth <= 2:
# 	179 : 90Percentile [NUMERICAL]
# 	128 : Maximum [NUMERICAL]
# 	85 : Minimum [NUMERICAL]
# 	82 : TotalEnergy [NUMERICAL]
# 	78 : Median [NUMERICAL]
# 	71 : RootMeanSquared [NUMERICAL]
# 	65 : Uniformity [NUMERICAL]
# 	61 : Energy [NUMERICAL]
# 	58 : Entropy [NUMERICAL]
# 	51 : Kurtosis [NUMERICAL]
# 	42 : Mean [NUMERICAL]
# 	38 : Range [NUMERICAL]
# 	36 : Skewness [NUMERICAL]
# 	26 : RobustMeanAbsoluteDeviation [NUMERICAL]
# 	24 : InterquartileRange [NUMERICAL]
# 	14 : Variance [NUMERICAL]
# 	11 : MeanAbsoluteDeviation [NUMERICAL]
# 	10 : 10Percentile [NUMERICAL]
#
# Attribute in nodes with depth <= 3:
# 	185 : 90Percentile [NUMERICAL]
# 	133 : Maximum [NUMERICAL]
# 	104 : Minimum [NUMERICAL]
# 	98 : Median [NUMERICAL]
# 	85 : TotalEnergy [NUMERICAL]
# 	84 : Uniformity [NUMERICAL]
# 	79 : RootMeanSquared [NUMERICAL]
# 	72 : Entropy [NUMERICAL]
# 	70 : Energy [NUMERICAL]
# 	62 : Range [NUMERICAL]
# 	61 : Kurtosis [NUMERICAL]
# 	52 : Mean [NUMERICAL]
# 	49 : Skewness [NUMERICAL]
# 	32 : RobustMeanAbsoluteDeviation [NUMERICAL]
# 	26 : InterquartileRange [NUMERICAL]
# 	23 : 10Percentile [NUMERICAL]
# 	20 : Variance [NUMERICAL]
# 	18 : MeanAbsoluteDeviation [NUMERICAL]
#
# Attribute in nodes with depth <= 5:
# 	189 : 90Percentile [NUMERICAL]
# 	137 : Maximum [NUMERICAL]
# 	115 : Minimum [NUMERICAL]
# 	108 : Median [NUMERICAL]
# 	98 : Uniformity [NUMERICAL]
# 	89 : TotalEnergy [NUMERICAL]
# 	80 : RootMeanSquared [NUMERICAL]
# 	79 : Entropy [NUMERICAL]
# 	71 : Energy [NUMERICAL]
# 	69 : Range [NUMERICAL]
# 	64 : Kurtosis [NUMERICAL]
# 	55 : Mean [NUMERICAL]
# 	52 : Skewness [NUMERICAL]
# 	39 : RobustMeanAbsoluteDeviation [NUMERICAL]
# 	31 : InterquartileRange [NUMERICAL]
# 	30 : 10Percentile [NUMERICAL]
# 	23 : Variance [NUMERICAL]
# 	22 : MeanAbsoluteDeviation [NUMERICAL]
#
# Condition type in nodes:
# 	1351 : HigherCondition
# Condition type in nodes with depth <= 0:
# 	300 : HigherCondition
# Condition type in nodes with depth <= 1:
# 	700 : HigherCondition
# Condition type in nodes with depth <= 2:
# 	1059 : HigherCondition
# Condition type in nodes with depth <= 3:
# 	1253 : HigherCondition
# Condition type in nodes with depth <= 5:
# 	1351 : HigherCondition
# Node format: NOT_SET
#
# Training OOB:
# 	trees: 1, Out-of-bag evaluation: accuracy:0.938976 logloss:2.19954
# 	trees: 12, Out-of-bag evaluation: accuracy:0.913944 logloss:2.37827
# 	trees: 23, Out-of-bag evaluation: accuracy:0.941614 logloss:0.74243
# 	trees: 34, Out-of-bag evaluation: accuracy:0.960377 logloss:0.737295
# 	trees: 45, Out-of-bag evaluation: accuracy:0.961426 logloss:0.698966
# 	trees: 55, Out-of-bag evaluation: accuracy:0.961426 logloss:0.708801
# 	trees: 65, Out-of-bag evaluation: accuracy:0.960377 logloss:0.161565
# 	trees: 75, Out-of-bag evaluation: accuracy:0.960377 logloss:0.168286
# 	trees: 86, Out-of-bag evaluation: accuracy:0.962474 logloss:0.173426
# 	trees: 96, Out-of-bag evaluation: accuracy:0.962474 logloss:0.175141
# 	trees: 106, Out-of-bag evaluation: accuracy:0.962474 logloss:0.176261
# 	trees: 116, Out-of-bag evaluation: accuracy:0.962474 logloss:0.180152
# 	trees: 126, Out-of-bag evaluation: accuracy:0.962474 logloss:0.172099
# 	trees: 136, Out-of-bag evaluation: accuracy:0.962474 logloss:0.175372
# 	trees: 146, Out-of-bag evaluation: accuracy:0.962474 logloss:0.170443
# 	trees: 156, Out-of-bag evaluation: accuracy:0.962474 logloss:0.170091
# 	trees: 166, Out-of-bag evaluation: accuracy:0.962474 logloss:0.173419
# 	trees: 176, Out-of-bag evaluation: accuracy:0.962474 logloss:0.173272
# 	trees: 186, Out-of-bag evaluation: accuracy:0.962474 logloss:0.138422
# 	trees: 196, Out-of-bag evaluation: accuracy:0.962474 logloss:0.136771
# 	trees: 207, Out-of-bag evaluation: accuracy:0.962474 logloss:0.135528
# 	trees: 217, Out-of-bag evaluation: accuracy:0.962474 logloss:0.135293
# 	trees: 227, Out-of-bag evaluation: accuracy:0.962474 logloss:0.13377
# 	trees: 237, Out-of-bag evaluation: accuracy:0.962474 logloss:0.132715
# 	trees: 247, Out-of-bag evaluation: accuracy:0.962474 logloss:0.1324
# 	trees: 258, Out-of-bag evaluation: accuracy:0.962474 logloss:0.133654
# 	trees: 268, Out-of-bag evaluation: accuracy:0.962474 logloss:0.132617
# 	trees: 281, Out-of-bag evaluation: accuracy:0.962474 logloss:0.132525
# 	trees: 291, Out-of-bag evaluation: accuracy:0.962474 logloss:0.132758
# 	trees: 300, Out-of-bag evaluation: accuracy:0.962474 logloss:0.131771

# %%
# Model features
model.make_inspector().features()
# Out:
# ["10Percentile" (1; #0),
#  "90Percentile" (1; #1),
#  "Energy" (1; #2),
#  "Entropy" (1; #3),
#  "InterquartileRange" (1; #4),
#  "Kurtosis" (1; #5),
#  "Maximum" (1; #6),
#  "Mean" (1; #7),
#  "MeanAbsoluteDeviation" (1; #8),
#  "Median" (1; #9),
#  "Minimum" (1; #10),
#  "Range" (1; #11),
#  "RobustMeanAbsoluteDeviation" (1; #12),
#  "RootMeanSquared" (1; #13),
#  "Skewness" (1; #14),
#  "TotalEnergy" (1; #15),
#  "Uniformity" (1; #16),
#  "Variance" (1; #17)]

# %%
# Feature importance
model.make_inspector().variable_importances()
# Out:
# {'INV_MEAN_MIN_DEPTH': [("90Percentile" (1; #1), 0.3845619732302136),
#   ("Maximum" (1; #6), 0.3506550431013488),
#   ("TotalEnergy" (1; #15), 0.29808727332946927),
#   ("RootMeanSquared" (1; #13), 0.2975944449036951),
#   ("Minimum" (1; #10), 0.29435194681107046),
#   ("Energy" (1; #2), 0.2918862570220653),
#   ("Median" (1; #9), 0.28963320023998185),
#   ("Kurtosis" (1; #5), 0.2835149554138982),
#   ("Uniformity" (1; #16), 0.2802061071588214),
#   ("Entropy" (1; #3), 0.2796833363114431),
#   ("Mean" (1; #7), 0.2768515822836961),
#   ("Skewness" (1; #14), 0.2749782854449194),
#   ("Range" (1; #11), 0.2713701283946843),
#   ("RobustMeanAbsoluteDeviation" (1; #12), 0.26978041800976993),
#   ("InterquartileRange" (1; #4), 0.2670345809782369),
#   ("10Percentile" (1; #0), 0.26537685092455415),
#   ("Variance" (1; #17), 0.2652815879840075),
#   ("MeanAbsoluteDeviation" (1; #8), 0.2644994505338797)],
#  'NUM_AS_ROOT': [("90Percentile" (1; #1), 93.0),
#   ("Maximum" (1; #6), 73.0),
#   ("RootMeanSquared" (1; #13), 33.0),
#   ("TotalEnergy" (1; #15), 33.0),
#   ("Energy" (1; #2), 30.0),
#   ("Median" (1; #9), 17.0),
#   ("Entropy" (1; #3), 7.0),
#   ("Mean" (1; #7), 7.0),
#   ("Uniformity" (1; #16), 6.0),
#   ("RobustMeanAbsoluteDeviation" (1; #12), 1.0)],
#  'SUM_SCORE': [("90Percentile" (1; #1), 32042.50150335123),
#   ("Maximum" (1; #6), 23949.871998742045),
#   ("RootMeanSquared" (1; #13), 9205.893478205779),
#   ("TotalEnergy" (1; #15), 9030.805926648747),
#   ("Energy" (1; #2), 8296.901567878202),
#   ("Median" (1; #9), 4637.511042872958),
#   ("Entropy" (1; #3), 3679.8764115514114),
#   ("Uniformity" (1; #16), 3624.9821269269482),
#   ("Mean" (1; #7), 1912.5076217048816),
#   ("Minimum" (1; #10), 1698.3612389940752),
#   ("Kurtosis" (1; #5), 1065.3038417742544),
#   ("Range" (1; #11), 872.7166588361505),
#   ("RobustMeanAbsoluteDeviation" (1; #12), 519.5215001502881),
#   ("Skewness" (1; #14), 488.84993906665943),
#   ("InterquartileRange" (1; #4), 386.40769728870845),
#   ("MeanAbsoluteDeviation" (1; #8), 375.40861880074954),
#   ("Variance" (1; #17), 278.13995559724765),
#   ("10Percentile" (1; #0), 208.24238875894383)],
#  'NUM_NODES': [("90Percentile" (1; #1), 189.0),
#   ("Maximum" (1; #6), 137.0),
#   ("Minimum" (1; #10), 115.0),
#   ("Median" (1; #9), 108.0),
#   ("Uniformity" (1; #16), 98.0),
#   ("TotalEnergy" (1; #15), 89.0),
#   ("RootMeanSquared" (1; #13), 80.0),
#   ("Entropy" (1; #3), 79.0),
#   ("Energy" (1; #2), 71.0),
#   ("Range" (1; #11), 69.0),
#   ("Kurtosis" (1; #5), 64.0),
#   ("Mean" (1; #7), 55.0),
#   ("Skewness" (1; #14), 52.0),
#   ("RobustMeanAbsoluteDeviation" (1; #12), 39.0),
#   ("InterquartileRange" (1; #4), 31.0),
#   ("10Percentile" (1; #0), 30.0),
#   ("Variance" (1; #17), 23.0),
#   ("MeanAbsoluteDeviation" (1; #8), 22.0)]}

# %%
# Model self evaluation
model.make_inspector().evaluation()
# Out:
# Evaluation(num_examples=507, accuracy=0.9624737942101069, loss=0.13177095369140288, rmse=None, ndcg=None, aucs=None, auuc=None, qini=None)

# %%
logs = model.make_inspector().training_logs()

plt.figure(figsize=(12, 4))
plt.subplot(1, 2, 1)
plt.plot([log.num_trees for log in logs], [log.evaluation.accuracy for log in logs])
plt.xlabel("Number of trees")
plt.ylabel("Accuracy (out-of-bag)")
plt.subplot(1, 2, 2)
plt.plot([log.num_trees for log in logs], [log.evaluation.loss for log in logs])
plt.xlabel("Number of trees")
plt.ylabel("Logloss (out-of-bag)")
plt.show()

# %% [markdown]
# Calculate the score of our hold-out validation dataset

# %%
predictions = model.predict(val_ds)
y_true      = validation_data["label"]

from sklearn.metrics import roc_auc_score
ROC_AUC = roc_auc_score(y_true, predictions)
print("The ROC AUC score is %.5f" % ROC_AUC )
# Out:
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 64ms/step
# The ROC AUC score is 1.00000

# %%
# Compute binary classification metrics with sklearn
import numpy as np
from sklearn.metrics import (
    accuracy_score,
    precision_score,
    recall_score,
    f1_score,
    roc_auc_score,
    average_precision_score,
    confusion_matrix,
    classification_report,
    matthews_corrcoef,
    log_loss,
    brier_score_loss,
)

# Get predictions (probabilities or class labels)
preds = model.predict(test_ds)
# If model outputs probabilities, convert to labels by threshold 0.5
if preds.ndim == 2:
    # For TFDF classification, preds may be class probabilities with shape (N, 2)
    if preds.shape[1] == 2:
        pos_probs = preds[:, 1]
    else:
        # If single-probability column (positive class)
        pos_probs = preds[:, -1]
    y_pred = (pos_probs >= 0.5).astype(int)
else:
    # Already class labels
    y_pred = preds.astype(int)
    pos_probs = None

# Ground truth labels (must be 0/1 integers)
y_true = test_data["label"].astype(int).to_numpy()

# Core metrics
metrics = {}
metrics["accuracy"] = accuracy_score(y_true, y_pred)
metrics["precision"] = precision_score(y_true, y_pred, zero_division=0)
metrics["recall"] = recall_score(y_true, y_pred, zero_division=0)
metrics["f1"] = f1_score(y_true, y_pred, zero_division=0)
metrics["mcc"] = matthews_corrcoef(y_true, y_pred)

# Probabilistic metrics (only if we have probabilities)
if pos_probs is not None:
    metrics["roc_auc"] = roc_auc_score(y_true, pos_probs)
    metrics["pr_auc"] = average_precision_score(y_true, pos_probs)
    metrics["log_loss"] = log_loss(y_true, pos_probs, labels=[0,1])
    metrics["brier_score"] = brier_score_loss(y_true, pos_probs)

# Confusion matrix and detailed report
cm = confusion_matrix(y_true, y_pred, labels=[0,1])
report = classification_report(y_true, y_pred, digits=4)

print("Sklearn binary metrics:")
for k, v in metrics.items():
    print(f"{k}: {v:.4f}")
print("\nConfusion matrix:\n", cm)
print("\nClassification report:\n", report)
# Out:
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 70ms/step
# Sklearn binary metrics:
# accuracy: 0.9863
# precision: 0.7778
# recall: 1.0000
# f1: 0.8750
# mcc: 0.8755
# roc_auc: 1.0000
# pr_auc: 1.0000
# log_loss: 0.0347
# brier_score: 0.0103
#
# Confusion matrix:
#  [[137   2]
#  [  0   7]]
#
# Classification report:
#                precision    recall  f1-score   support
#
#            0     1.0000    0.9856    0.9928       139
#            1     0.7778    1.0000    0.8750         7
#
#     accuracy                         0.9863       146
#    macro avg     0.8889    0.9928    0.9339       146
# weighted avg     0.9893    0.9863    0.9871       146
