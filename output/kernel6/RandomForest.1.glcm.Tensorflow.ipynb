# %%
# Import packages and modules
import numpy  as np
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow_decision_forests as tfdf

from sklearn.model_selection import train_test_split
# Out:
# 2026-08-12 05:57:26.527572: I tensorflow/core/util/port.cc:113] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2026-08-12 05:57:26.888660: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2026-08-12 05:57:31.492792: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
# Check the version of TensorFlow Decision Forests
print("Found TensorFlow Decision Forests v" + tfdf.__version__)
# Out:
# Found TensorFlow Decision Forests v1.9.1

# %%
datasetPath = 'dataset/firstorder/kernel5-radius5/dataset.csv'

# %%
# Parameters
datasetPath = "dataset/glcm/kernel6-radius6/1.dataset.csv"

# %%
# train/validation/test = 70/10/20
dataset = pd.read_csv(datasetPath)

train_data, temp_data = train_test_split(dataset, test_size=0.3, random_state=42)
validation_data, test_data = train_test_split(temp_data, test_size=2/3, random_state=42)

# %%
from sklearn.utils.class_weight import compute_class_weight

# tinh class weight tren tap train
classes = np.array([0, 1])
weights = compute_class_weight(class_weight="balanced", classes=classes, y=train_data["label"])
class_weight = {0: weights[0], 1: weights[1]}

# gan sample_weight cho tung dong
train_data["sample_weight"] = train_data["label"].map(class_weight)
validation_data["sample_weight"] = validation_data["label"].map(class_weight)
test_data["sample_weight"] = test_data["label"].map(class_weight)

# Convert the dataset into a TensorFlow dataset.
train_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    train_data, label="label", weight="sample_weight"
)         
val_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    validation_data, label="label", weight="sample_weight"
)
test_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    test_data, label="label", weight="sample_weight"
)
# Out:
# 2026-08-12 05:57:44.006703: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:984] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2026-08-12 05:57:44.008324: W tensorflow/core/common_runtime/gpu/gpu_device.cc:2251] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...

# %%
import keras

# %%
# %%time

# Train a Random Forest model.
model = tfdf.keras.RandomForestModel()

# Add evaluation metrics
model.compile(
    metrics=["accuracy"]
)
model.fit(x=train_ds)

# # Train a Gradient Boosted Trees model.
# model = tfdf.keras.GradientBoostedTreesModel(num_trees=1500)
# model.fit(train_ds)
# Out:
# Use /tmp/tmpojq8u1n0 as temporary training directory
# Reading training dataset...
# Training dataset read in 0:00:05.278152. Found 450 examples.
# Training model...
# Model trained in 0:00:00.050261
# Compiling model...
# [INFO 26-08-12 05:57:49.5052 UTC kernel.cc:1233] Loading model from path /tmp/tmpojq8u1n0/model/ with prefix 3853753a8d8c4fc1
# [INFO 26-08-12 05:57:49.5128 UTC decision_forest.cc:734] Model loaded with 300 root(s), 6550 node(s), and 24 input feature(s).
# [INFO 26-08-12 05:57:49.5128 UTC abstract_model.cc:1362] Engine "RandomForestOptPred" built
# [INFO 26-08-12 05:57:49.5128 UTC kernel.cc:1061] Use fast generic engine
# Model compiled.
# CPU times: user 5.69 s, sys: 46.9 ms, total: 5.74 s
# Wall time: 8.42 s

# %%
# Evaluate the model
evaluate = model.evaluate(val_ds, return_dict=True)
print()

for name, value in evaluate.items():
    print(f"{name}: {value:.4f}")
# Out:
# WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 1/1 [==============================] - ETA: 0s - loss: 0.0000e+00 - accuracy: 0.9062
# 1/1 [==============================] - 3s 3s/step - loss: 0.0000e+00 - accuracy: 0.9062
# loss: 0.0000
# accuracy: 0.9062

# %%
# Model Summary
model.summary()
# Out:
# Model: "random_forest_model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
# =================================================================
# Total params: 1 (1.00 Byte)
# Trainable params: 0 (0.00 Byte)
# Non-trainable params: 1 (1.00 Byte)
# _________________________________________________________________
# Type: "RANDOM_FOREST"
# Task: CLASSIFICATION
# Label: "__LABEL"
#
# Input Features (24):
# 	Autocorrelation
# 	ClusterProminence
# 	ClusterShade
# 	ClusterTendency
# 	Contrast
# 	Correlation
# 	DifferenceAverage
# 	DifferenceEntropy
# 	DifferenceVariance
# 	Id
# 	Idm
# 	Idmn
# 	Idn
# 	Imc1
# 	Imc2
# 	InverseVariance
# 	JointAverage
# 	JointEnergy
# 	JointEntropy
# 	MCC
# 	MaximumProbability
# 	SumAverage
# 	SumEntropy
# 	SumSquares
#
# Trained with weights
#
# Variable Importance: INV_MEAN_MIN_DEPTH:
#     1.    "Autocorrelation"  0.285882 ################
#     2.       "JointAverage"  0.273345 #############
#     3.         "SumAverage"  0.259590 ###########
#     4.               "Imc1"  0.225368 #####
#     5.                "MCC"  0.222689 ####
#     6.               "Imc2"  0.218332 ###
#     7.    "InverseVariance"  0.217775 ###
#     8.        "Correlation"  0.217099 ###
#     9. "DifferenceVariance"  0.212233 ##
#    10. "MaximumProbability"  0.207380 #
#    11.         "SumEntropy"  0.203933 #
#    12.               "Idmn"  0.203055 #
#    13.           "Contrast"  0.201868
#    14.        "JointEnergy"  0.200343
#    15.  "DifferenceEntropy"  0.200048
#    16.       "ClusterShade"  0.199639
#    17.                "Idm"  0.198054
#    18.  "DifferenceAverage"  0.197636
#    19.    "ClusterTendency"  0.197540
#    20.         "SumSquares"  0.197088
#    21.       "JointEntropy"  0.196670
#    22.                 "Id"  0.196568
#    23.  "ClusterProminence"  0.196520
#    24.                "Idn"  0.196360
#
# Variable Importance: NUM_AS_ROOT:
#     1.    "Autocorrelation" 66.000000 ################
#     2.       "JointAverage" 57.000000 #############
#     3.         "SumAverage" 48.000000 ###########
#     4.               "Imc1" 21.000000 ####
#     5.    "InverseVariance" 17.000000 ###
#     6. "DifferenceVariance" 14.000000 ###
#     7.                "MCC" 14.000000 ###
#     8. "MaximumProbability" 14.000000 ###
#     9.               "Imc2" 13.000000 ##
#    10.        "Correlation" 12.000000 ##
#    11.         "SumEntropy"  7.000000 #
#    12.           "Contrast"  5.000000
#    13.               "Idmn"  5.000000
#    14.        "JointEnergy"  5.000000
#    15.       "ClusterShade"  1.000000
#    16.       "JointEntropy"  1.000000
#
# Variable Importance: NUM_NODES:
#     1.    "Autocorrelation" 352.000000 ################
#     2.       "JointAverage" 322.000000 ##############
#     3.         "SumAverage" 288.000000 ############
#     4.               "Imc1" 177.000000 ######
#     5.               "Imc2" 165.000000 #####
#     6.                "MCC" 165.000000 #####
#     7.    "InverseVariance" 160.000000 #####
#     8.        "Correlation" 142.000000 ####
#     9. "DifferenceVariance" 120.000000 ###
#    10.         "SumEntropy" 100.000000 ##
#    11.               "Idmn" 95.000000 #
#    12. "MaximumProbability" 95.000000 #
#    13.           "Contrast" 92.000000 #
#    14.    "ClusterTendency" 88.000000 #
#    15.  "DifferenceEntropy" 87.000000 #
#    16.       "ClusterShade" 83.000000 #
#    17.                "Idm" 83.000000 #
#    18.         "SumSquares" 82.000000 #
#    19.        "JointEnergy" 81.000000 #
#    20.                 "Id" 78.000000
#    21.       "JointEntropy" 72.000000
#    22.  "DifferenceAverage" 70.000000
#    23.                "Idn" 66.000000
#    24.  "ClusterProminence" 62.000000
#
# Variable Importance: SUM_SCORE:
#     1.    "Autocorrelation" 20607.794162 ################
#     2.       "JointAverage" 18703.126041 ##############
#     3.         "SumAverage" 16690.471610 ############
#     4.               "Imc1" 3911.766694 ##
#     5.               "Imc2" 3768.512901 ##
#     6.                "MCC" 3208.222655 ##
#     7.    "InverseVariance" 3058.185165 ##
#     8.        "Correlation" 3006.753570 ##
#     9. "DifferenceVariance" 2100.433527 #
#    10.         "SumEntropy" 1527.256646
#    11. "MaximumProbability" 1484.816960
#    12.               "Idmn" 1219.981166
#    13.        "JointEnergy" 1081.648365
#    14.           "Contrast" 1042.894818
#    15.       "ClusterShade" 1026.357270
#    16.                "Idm" 909.062142
#    17.  "DifferenceEntropy" 866.492567
#    18.                 "Id" 740.333895
#    19.    "ClusterTendency" 734.139973
#    20.       "JointEntropy" 697.469448
#    21.         "SumSquares" 637.131147
#    22.                "Idn" 628.044102
#    23.  "DifferenceAverage" 624.888192
#    24.  "ClusterProminence" 480.203588
#
#
#
# Winner takes all: true
# Out-of-bag evaluation: accuracy:0.924143 logloss:0.45973
# Number of trees: 300
# Total number of nodes: 6550
#
# Number of nodes by tree:
# Count: 300 Average: 21.8333 StdDev: 3.34448
# Min: 13 Max: 33 Ignored: 0
# ----------------------------------------------
# [ 13, 14)  2   0.67%   0.67%
# [ 14, 15)  0   0.00%   0.67%
# [ 15, 16)  9   3.00%   3.67% #
# [ 16, 17)  0   0.00%   3.67%
# [ 17, 18) 29   9.67%  13.33% ####
# [ 18, 19)  0   0.00%  13.33%
# [ 19, 20) 46  15.33%  28.67% ######
# [ 20, 21)  0   0.00%  28.67%
# [ 21, 22) 67  22.33%  51.00% #########
# [ 22, 23)  0   0.00%  51.00%
# [ 23, 24) 72  24.00%  75.00% ##########
# [ 24, 25)  0   0.00%  75.00%
# [ 25, 26) 46  15.33%  90.33% ######
# [ 26, 27)  0   0.00%  90.33%
# [ 27, 28) 19   6.33%  96.67% ###
# [ 28, 29)  0   0.00%  96.67%
# [ 29, 30)  8   2.67%  99.33% #
# [ 30, 31)  0   0.00%  99.33%
# [ 31, 32)  1   0.33%  99.67%
# [ 32, 33]  1   0.33% 100.00%
#
# Depth by leafs:
# Count: 3425 Average: 4.25781 StdDev: 1.61917
# Min: 1 Max: 10 Ignored: 0
# ----------------------------------------------
# [  1,  2)  49   1.43%   1.43% #
# [  2,  3) 392  11.45%  12.88% #####
# [  3,  4) 772  22.54%  35.42% #########
# [  4,  5) 846  24.70%  60.12% ##########
# [  5,  6) 627  18.31%  78.42% #######
# [  6,  7) 424  12.38%  90.80% #####
# [  7,  8) 192   5.61%  96.41% ##
# [  8,  9)  90   2.63%  99.04% #
# [  9, 10)  23   0.67%  99.71%
# [ 10, 10]  10   0.29% 100.00%
#
# Number of training obs by leaf:
# Count: 3425 Average: 39.4161 StdDev: 67.6951
# Min: 5 Max: 360 Ignored: 0
# ----------------------------------------------
# [   5,  22) 2343  68.41%  68.41% ##########
# [  22,  40)  328   9.58%  77.99% #
# [  40,  58)  188   5.49%  83.47% #
# [  58,  76)   55   1.61%  85.08%
# [  76,  94)   35   1.02%  86.10%
# [  94, 111)   42   1.23%  87.33%
# [ 111, 129)   65   1.90%  89.23%
# [ 129, 147)   46   1.34%  90.57%
# [ 147, 165)   48   1.40%  91.97%
# [ 165, 183)   42   1.23%  93.20%
# [ 183, 200)   27   0.79%  93.99%
# [ 200, 218)   39   1.14%  95.12%
# [ 218, 236)   36   1.05%  96.18%
# [ 236, 254)   35   1.02%  97.20%
# [ 254, 272)   19   0.55%  97.75%
# [ 272, 289)   26   0.76%  98.51%
# [ 289, 307)   24   0.70%  99.21%
# [ 307, 325)   15   0.44%  99.65%
# [ 325, 343)    9   0.26%  99.91%
# [ 343, 360]    3   0.09% 100.00%
#
# Attribute in nodes:
# 	352 : Autocorrelation [NUMERICAL]
# 	322 : JointAverage [NUMERICAL]
# 	288 : SumAverage [NUMERICAL]
# 	177 : Imc1 [NUMERICAL]
# 	165 : MCC [NUMERICAL]
# 	165 : Imc2 [NUMERICAL]
# 	160 : InverseVariance [NUMERICAL]
# 	142 : Correlation [NUMERICAL]
# 	120 : DifferenceVariance [NUMERICAL]
# 	100 : SumEntropy [NUMERICAL]
# 	95 : MaximumProbability [NUMERICAL]
# 	95 : Idmn [NUMERICAL]
# 	92 : Contrast [NUMERICAL]
# 	88 : ClusterTendency [NUMERICAL]
# 	87 : DifferenceEntropy [NUMERICAL]
# 	83 : Idm [NUMERICAL]
# 	83 : ClusterShade [NUMERICAL]
# 	82 : SumSquares [NUMERICAL]
# 	81 : JointEnergy [NUMERICAL]
# 	78 : Id [NUMERICAL]
# 	72 : JointEntropy [NUMERICAL]
# 	70 : DifferenceAverage [NUMERICAL]
# 	66 : Idn [NUMERICAL]
# 	62 : ClusterProminence [NUMERICAL]
#
# Attribute in nodes with depth <= 0:
# 	66 : Autocorrelation [NUMERICAL]
# 	57 : JointAverage [NUMERICAL]
# 	48 : SumAverage [NUMERICAL]
# 	21 : Imc1 [NUMERICAL]
# 	17 : InverseVariance [NUMERICAL]
# 	14 : MaximumProbability [NUMERICAL]
# 	14 : MCC [NUMERICAL]
# 	14 : DifferenceVariance [NUMERICAL]
# 	13 : Imc2 [NUMERICAL]
# 	12 : Correlation [NUMERICAL]
# 	7 : SumEntropy [NUMERICAL]
# 	5 : JointEnergy [NUMERICAL]
# 	5 : Idmn [NUMERICAL]
# 	5 : Contrast [NUMERICAL]
# 	1 : JointEntropy [NUMERICAL]
# 	1 : ClusterShade [NUMERICAL]
#
# Attribute in nodes with depth <= 1:
# 	156 : Autocorrelation [NUMERICAL]
# 	137 : SumAverage [NUMERICAL]
# 	136 : JointAverage [NUMERICAL]
# 	56 : Imc2 [NUMERICAL]
# 	50 : MCC [NUMERICAL]
# 	50 : Imc1 [NUMERICAL]
# 	37 : Correlation [NUMERICAL]
# 	35 : InverseVariance [NUMERICAL]
# 	33 : DifferenceVariance [NUMERICAL]
# 	30 : SumEntropy [NUMERICAL]
# 	21 : MaximumProbability [NUMERICAL]
# 	21 : ClusterShade [NUMERICAL]
# 	18 : Idmn [NUMERICAL]
# 	16 : Contrast [NUMERICAL]
# 	12 : JointEnergy [NUMERICAL]
# 	11 : JointEntropy [NUMERICAL]
# 	6 : DifferenceEntropy [NUMERICAL]
# 	5 : Idn [NUMERICAL]
# 	5 : Idm [NUMERICAL]
# 	4 : Id [NUMERICAL]
# 	4 : ClusterTendency [NUMERICAL]
# 	4 : ClusterProminence [NUMERICAL]
# 	3 : DifferenceAverage [NUMERICAL]
# 	1 : SumSquares [NUMERICAL]
#
# Attribute in nodes with depth <= 2:
# 	229 : Autocorrelation [NUMERICAL]
# 	220 : JointAverage [NUMERICAL]
# 	188 : SumAverage [NUMERICAL]
# 	95 : Imc2 [NUMERICAL]
# 	93 : MCC [NUMERICAL]
# 	87 : Imc1 [NUMERICAL]
# 	81 : Correlation [NUMERICAL]
# 	71 : InverseVariance [NUMERICAL]
# 	57 : DifferenceVariance [NUMERICAL]
# 	46 : SumEntropy [NUMERICAL]
# 	42 : Idmn [NUMERICAL]
# 	41 : MaximumProbability [NUMERICAL]
# 	38 : Contrast [NUMERICAL]
# 	36 : ClusterShade [NUMERICAL]
# 	30 : DifferenceEntropy [NUMERICAL]
# 	28 : DifferenceAverage [NUMERICAL]
# 	27 : JointEntropy [NUMERICAL]
# 	26 : JointEnergy [NUMERICAL]
# 	26 : Idm [NUMERICAL]
# 	25 : Idn [NUMERICAL]
# 	23 : Id [NUMERICAL]
# 	19 : ClusterTendency [NUMERICAL]
# 	18 : SumSquares [NUMERICAL]
# 	15 : ClusterProminence [NUMERICAL]
#
# Attribute in nodes with depth <= 3:
# 	287 : Autocorrelation [NUMERICAL]
# 	272 : JointAverage [NUMERICAL]
# 	239 : SumAverage [NUMERICAL]
# 	122 : Imc2 [NUMERICAL]
# 	119 : Imc1 [NUMERICAL]
# 	115 : MCC [NUMERICAL]
# 	114 : InverseVariance [NUMERICAL]
# 	106 : Correlation [NUMERICAL]
# 	91 : DifferenceVariance [NUMERICAL]
# 	67 : Idmn [NUMERICAL]
# 	64 : Contrast [NUMERICAL]
# 	60 : SumEntropy [NUMERICAL]
# 	59 : MaximumProbability [NUMERICAL]
# 	57 : DifferenceEntropy [NUMERICAL]
# 	54 : JointEnergy [NUMERICAL]
# 	51 : ClusterShade [NUMERICAL]
# 	48 : Idm [NUMERICAL]
# 	46 : DifferenceAverage [NUMERICAL]
# 	45 : Id [NUMERICAL]
# 	44 : Idn [NUMERICAL]
# 	41 : JointEntropy [NUMERICAL]
# 	41 : ClusterTendency [NUMERICAL]
# 	39 : SumSquares [NUMERICAL]
# 	28 : ClusterProminence [NUMERICAL]
#
# Attribute in nodes with depth <= 5:
# 	343 : Autocorrelation [NUMERICAL]
# 	315 : JointAverage [NUMERICAL]
# 	283 : SumAverage [NUMERICAL]
# 	161 : Imc1 [NUMERICAL]
# 	157 : Imc2 [NUMERICAL]
# 	152 : InverseVariance [NUMERICAL]
# 	148 : MCC [NUMERICAL]
# 	132 : Correlation [NUMERICAL]
# 	115 : DifferenceVariance [NUMERICAL]
# 	93 : SumEntropy [NUMERICAL]
# 	89 : Idmn [NUMERICAL]
# 	87 : MaximumProbability [NUMERICAL]
# 	84 : DifferenceEntropy [NUMERICAL]
# 	81 : Contrast [NUMERICAL]
# 	78 : JointEnergy [NUMERICAL]
# 	77 : ClusterTendency [NUMERICAL]
# 	76 : Idm [NUMERICAL]
# 	75 : ClusterShade [NUMERICAL]
# 	73 : Id [NUMERICAL]
# 	72 : SumSquares [NUMERICAL]
# 	65 : DifferenceAverage [NUMERICAL]
# 	62 : Idn [NUMERICAL]
# 	61 : JointEntropy [NUMERICAL]
# 	53 : ClusterProminence [NUMERICAL]
#
# Condition type in nodes:
# 	3125 : HigherCondition
# Condition type in nodes with depth <= 0:
# 	300 : HigherCondition
# Condition type in nodes with depth <= 1:
# 	851 : HigherCondition
# Condition type in nodes with depth <= 2:
# 	1561 : HigherCondition
# Condition type in nodes with depth <= 3:
# 	2209 : HigherCondition
# Condition type in nodes with depth <= 5:
# 	2932 : HigherCondition
# Node format: NOT_SET
#
# Training OOB:
# 	trees: 1, Out-of-bag evaluation: accuracy:0.915849 logloss:3.0331
# 	trees: 11, Out-of-bag evaluation: accuracy:0.888462 logloss:2.98056
# 	trees: 22, Out-of-bag evaluation: accuracy:0.886215 logloss:0.553016
# 	trees: 32, Out-of-bag evaluation: accuracy:0.913376 logloss:0.565779
# 	trees: 42, Out-of-bag evaluation: accuracy:0.898268 logloss:0.561793
# 	trees: 52, Out-of-bag evaluation: accuracy:0.914661 logloss:0.549789
# 	trees: 62, Out-of-bag evaluation: accuracy:0.921573 logloss:0.548698
# 	trees: 73, Out-of-bag evaluation: accuracy:0.920287 logloss:0.545947
# 	trees: 83, Out-of-bag evaluation: accuracy:0.905179 logloss:0.548518
# 	trees: 93, Out-of-bag evaluation: accuracy:0.90775 logloss:0.548536
# 	trees: 105, Out-of-bag evaluation: accuracy:0.913376 logloss:0.546107
# 	trees: 115, Out-of-bag evaluation: accuracy:0.913376 logloss:0.506084
# 	trees: 125, Out-of-bag evaluation: accuracy:0.899553 logloss:0.509158
# 	trees: 135, Out-of-bag evaluation: accuracy:0.899553 logloss:0.511669
# 	trees: 145, Out-of-bag evaluation: accuracy:0.909035 logloss:0.508402
# 	trees: 156, Out-of-bag evaluation: accuracy:0.909035 logloss:0.505278
# 	trees: 166, Out-of-bag evaluation: accuracy:0.909035 logloss:0.503714
# 	trees: 177, Out-of-bag evaluation: accuracy:0.909035 logloss:0.503833
# 	trees: 188, Out-of-bag evaluation: accuracy:0.909035 logloss:0.502619
# 	trees: 199, Out-of-bag evaluation: accuracy:0.917232 logloss:0.500206
# 	trees: 209, Out-of-bag evaluation: accuracy:0.917232 logloss:0.49892
# 	trees: 221, Out-of-bag evaluation: accuracy:0.915947 logloss:0.500006
# 	trees: 231, Out-of-bag evaluation: accuracy:0.915947 logloss:0.500437
# 	trees: 241, Out-of-bag evaluation: accuracy:0.915947 logloss:0.459081
# 	trees: 251, Out-of-bag evaluation: accuracy:0.914661 logloss:0.459893
# 	trees: 261, Out-of-bag evaluation: accuracy:0.914661 logloss:0.460078
# 	trees: 271, Out-of-bag evaluation: accuracy:0.924143 logloss:0.459005
# 	trees: 281, Out-of-bag evaluation: accuracy:0.915947 logloss:0.458991
# 	trees: 291, Out-of-bag evaluation: accuracy:0.915947 logloss:0.458858
# 	trees: 300, Out-of-bag evaluation: accuracy:0.924143 logloss:0.45973

# %%
# Model features
model.make_inspector().features()
# Out:
# ["Autocorrelation" (1; #0),
#  "ClusterProminence" (1; #1),
#  "ClusterShade" (1; #2),
#  "ClusterTendency" (1; #3),
#  "Contrast" (1; #4),
#  "Correlation" (1; #5),
#  "DifferenceAverage" (1; #6),
#  "DifferenceEntropy" (1; #7),
#  "DifferenceVariance" (1; #8),
#  "Id" (1; #9),
#  "Idm" (1; #10),
#  "Idmn" (1; #11),
#  "Idn" (1; #12),
#  "Imc1" (1; #13),
#  "Imc2" (1; #14),
#  "InverseVariance" (1; #15),
#  "JointAverage" (1; #16),
#  "JointEnergy" (1; #17),
#  "JointEntropy" (1; #18),
#  "MCC" (1; #19),
#  "MaximumProbability" (1; #20),
#  "SumAverage" (1; #21),
#  "SumEntropy" (1; #22),
#  "SumSquares" (1; #23)]

# %%
# Feature importance
model.make_inspector().variable_importances()
# Out:
# {'INV_MEAN_MIN_DEPTH': [("Autocorrelation" (1; #0), 0.285882353005411),
#   ("JointAverage" (1; #16), 0.2733448319969665),
#   ("SumAverage" (1; #21), 0.2595903813544495),
#   ("Imc1" (1; #13), 0.22536846829645796),
#   ("MCC" (1; #19), 0.22268945734741558),
#   ("Imc2" (1; #14), 0.21833239163008886),
#   ("InverseVariance" (1; #15), 0.21777525220522082),
#   ("Correlation" (1; #5), 0.21709867056725465),
#   ("DifferenceVariance" (1; #8), 0.21223304293256243),
#   ("MaximumProbability" (1; #20), 0.2073802485835858),
#   ("SumEntropy" (1; #22), 0.20393331473418339),
#   ("Idmn" (1; #11), 0.20305522467766673),
#   ("Contrast" (1; #4), 0.2018677613513119),
#   ("JointEnergy" (1; #17), 0.2003428738876215),
#   ("DifferenceEntropy" (1; #7), 0.20004827423628377),
#   ("ClusterShade" (1; #2), 0.19963879616300342),
#   ("Idm" (1; #10), 0.1980539818937359),
#   ("DifferenceAverage" (1; #6), 0.19763602296463065),
#   ("ClusterTendency" (1; #3), 0.19754036456097301),
#   ("SumSquares" (1; #23), 0.19708842678678629),
#   ("JointEntropy" (1; #18), 0.1966696268577236),
#   ("Id" (1; #9), 0.19656756759907343),
#   ("ClusterProminence" (1; #1), 0.19651977343226812),
#   ("Idn" (1; #12), 0.19635980175264253)],
#  'NUM_AS_ROOT': [("Autocorrelation" (1; #0), 66.0),
#   ("JointAverage" (1; #16), 57.0),
#   ("SumAverage" (1; #21), 48.0),
#   ("Imc1" (1; #13), 21.0),
#   ("InverseVariance" (1; #15), 17.0),
#   ("DifferenceVariance" (1; #8), 14.0),
#   ("MCC" (1; #19), 14.0),
#   ("MaximumProbability" (1; #20), 14.0),
#   ("Imc2" (1; #14), 13.0),
#   ("Correlation" (1; #5), 12.0),
#   ("SumEntropy" (1; #22), 7.0),
#   ("Contrast" (1; #4), 5.0),
#   ("Idmn" (1; #11), 5.0),
#   ("JointEnergy" (1; #17), 5.0),
#   ("ClusterShade" (1; #2), 1.0),
#   ("JointEntropy" (1; #18), 1.0)],
#  'SUM_SCORE': [("Autocorrelation" (1; #0), 20607.794162172217),
#   ("JointAverage" (1; #16), 18703.126040760562),
#   ("SumAverage" (1; #21), 16690.47160996846),
#   ("Imc1" (1; #13), 3911.7666943309887),
#   ("Imc2" (1; #14), 3768.5129008197136),
#   ("MCC" (1; #19), 3208.2226549155803),
#   ("InverseVariance" (1; #15), 3058.185165344174),
#   ("Correlation" (1; #5), 3006.7535697426706),
#   ("DifferenceVariance" (1; #8), 2100.4335265999557),
#   ("SumEntropy" (1; #22), 1527.2566460226567),
#   ("MaximumProbability" (1; #20), 1484.8169604279876),
#   ("Idmn" (1; #11), 1219.9811656785096),
#   ("JointEnergy" (1; #17), 1081.6483653441258),
#   ("Contrast" (1; #4), 1042.8948183803313),
#   ("ClusterShade" (1; #2), 1026.3572703185228),
#   ("Idm" (1; #10), 909.0621418427324),
#   ("DifferenceEntropy" (1; #7), 866.4925673625484),
#   ("Id" (1; #9), 740.3338953061192),
#   ("ClusterTendency" (1; #3), 734.1399729877548),
#   ("JointEntropy" (1; #18), 697.4694478957215),
#   ("SumSquares" (1; #23), 637.1311473948228),
#   ("Idn" (1; #12), 628.0441016341294),
#   ("DifferenceAverage" (1; #6), 624.8881920380254),
#   ("ClusterProminence" (1; #1), 480.2035878230397)],
#  'NUM_NODES': [("Autocorrelation" (1; #0), 352.0),
#   ("JointAverage" (1; #16), 322.0),
#   ("SumAverage" (1; #21), 288.0),
#   ("Imc1" (1; #13), 177.0),
#   ("Imc2" (1; #14), 165.0),
#   ("MCC" (1; #19), 165.0),
#   ("InverseVariance" (1; #15), 160.0),
#   ("Correlation" (1; #5), 142.0),
#   ("DifferenceVariance" (1; #8), 120.0),
#   ("SumEntropy" (1; #22), 100.0),
#   ("Idmn" (1; #11), 95.0),
#   ("MaximumProbability" (1; #20), 95.0),
#   ("Contrast" (1; #4), 92.0),
#   ("ClusterTendency" (1; #3), 88.0),
#   ("DifferenceEntropy" (1; #7), 87.0),
#   ("ClusterShade" (1; #2), 83.0),
#   ("Idm" (1; #10), 83.0),
#   ("SumSquares" (1; #23), 82.0),
#   ("JointEnergy" (1; #17), 81.0),
#   ("Id" (1; #9), 78.0),
#   ("JointEntropy" (1; #18), 72.0),
#   ("DifferenceAverage" (1; #6), 70.0),
#   ("Idn" (1; #12), 66.0),
#   ("ClusterProminence" (1; #1), 62.0)]}

# %%
# Model self evaluation
model.make_inspector().evaluation()
# Out:
# Evaluation(num_examples=450, accuracy=0.9241434532537885, loss=0.4597300797451532, rmse=None, ndcg=None, aucs=None, auuc=None, qini=None)

# %%
logs = model.make_inspector().training_logs()

plt.figure(figsize=(12, 4))
plt.subplot(1, 2, 1)
plt.plot([log.num_trees for log in logs], [log.evaluation.accuracy for log in logs])
plt.xlabel("Number of trees")
plt.ylabel("Accuracy (out-of-bag)")
plt.subplot(1, 2, 2)
plt.plot([log.num_trees for log in logs], [log.evaluation.loss for log in logs])
plt.xlabel("Number of trees")
plt.ylabel("Logloss (out-of-bag)")
plt.show()

# %% [markdown]
# Calculate the score of our hold-out validation dataset

# %%
predictions = model.predict(val_ds)
y_true      = validation_data["label"]

from sklearn.metrics import roc_auc_score
ROC_AUC = roc_auc_score(y_true, predictions)
print("The ROC AUC score is %.5f" % ROC_AUC )
# Out:
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 63ms/step
# The ROC AUC score is 0.96226

# %%
# Compute binary classification metrics with sklearn
import numpy as np
from sklearn.metrics import (
    accuracy_score,
    precision_score,
    recall_score,
    f1_score,
    roc_auc_score,
    average_precision_score,
    confusion_matrix,
    classification_report,
    matthews_corrcoef,
    log_loss,
    brier_score_loss,
)

# Get predictions (probabilities or class labels)
preds = model.predict(test_ds)
# If model outputs probabilities, convert to labels by threshold 0.5
if preds.ndim == 2:
    # For TFDF classification, preds may be class probabilities with shape (N, 2)
    if preds.shape[1] == 2:
        pos_probs = preds[:, 1]
    else:
        # If single-probability column (positive class)
        pos_probs = preds[:, -1]
    y_pred = (pos_probs >= 0.5).astype(int)
else:
    # Already class labels
    y_pred = preds.astype(int)
    pos_probs = None

# Ground truth labels (must be 0/1 integers)
y_true = test_data["label"].astype(int).to_numpy()

# Core metrics
metrics = {}
metrics["accuracy"] = accuracy_score(y_true, y_pred)
metrics["precision"] = precision_score(y_true, y_pred, zero_division=0)
metrics["recall"] = recall_score(y_true, y_pred, zero_division=0)
metrics["f1"] = f1_score(y_true, y_pred, zero_division=0)
metrics["mcc"] = matthews_corrcoef(y_true, y_pred)

# Probabilistic metrics (only if we have probabilities)
if pos_probs is not None:
    metrics["roc_auc"] = roc_auc_score(y_true, pos_probs)
    metrics["pr_auc"] = average_precision_score(y_true, pos_probs)
    metrics["log_loss"] = log_loss(y_true, pos_probs, labels=[0,1])
    metrics["brier_score"] = brier_score_loss(y_true, pos_probs)

# Confusion matrix and detailed report
cm = confusion_matrix(y_true, y_pred, labels=[0,1])
report = classification_report(y_true, y_pred, digits=4)

print("Sklearn binary metrics:")
for k, v in metrics.items():
    print(f"{k}: {v:.4f}")
print("\nConfusion matrix:\n", cm)
print("\nClassification report:\n", report)
# Out:
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 69ms/step
# Sklearn binary metrics:
# accuracy: 0.9690
# precision: 0.8500
# recall: 0.9444
# f1: 0.8947
# mcc: 0.8783
# roc_auc: 0.9785
# pr_auc: 0.9335
# log_loss: 0.1265
# brier_score: 0.0350
#
# Confusion matrix:
#  [[108   3]
#  [  1  17]]
#
# Classification report:
#                precision    recall  f1-score   support
#
#            0     0.9908    0.9730    0.9818       111
#            1     0.8500    0.9444    0.8947        18
#
#     accuracy                         0.9690       129
#    macro avg     0.9204    0.9587    0.9383       129
# weighted avg     0.9712    0.9690    0.9697       129
