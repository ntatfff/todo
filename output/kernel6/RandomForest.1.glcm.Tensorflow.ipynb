# %%
# Import packages and modules
import numpy  as np
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow_decision_forests as tfdf

from sklearn.model_selection import train_test_split
# Out:
# 2026-08-15 05:20:29.769415: I tensorflow/core/util/port.cc:113] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2026-08-15 05:20:30.128886: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2026-08-15 05:20:34.855211: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
# Check the version of TensorFlow Decision Forests
print("Found TensorFlow Decision Forests v" + tfdf.__version__)
# Out:
# Found TensorFlow Decision Forests v1.9.1

# %%
datasetPath = 'dataset/firstorder/kernel5/dataset.csv'

# %%
# Parameters
datasetPath = "dataset/glcm/kernel6/1.dataset.csv"

# %%
# train/validation/test = 70/10/20
dataset = pd.read_csv(datasetPath)

train_data, temp_data = train_test_split(dataset, test_size=0.3, random_state=42)
validation_data, test_data = train_test_split(temp_data, test_size=2/3, random_state=42)

# %%
from sklearn.utils.class_weight import compute_class_weight

# tinh class weight tren tap train
classes = np.array([0, 1])
weights = compute_class_weight(class_weight="balanced", classes=classes, y=train_data["label"])
class_weight = {0: weights[0], 1: weights[1]}

# gan sample_weight cho tung dong
train_data["sample_weight"] = train_data["label"].map(class_weight)
validation_data["sample_weight"] = validation_data["label"].map(class_weight)
test_data["sample_weight"] = test_data["label"].map(class_weight)

# Convert the dataset into a TensorFlow dataset.
train_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    train_data, label="label", weight="sample_weight"
)         
val_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    validation_data, label="label", weight="sample_weight"
)
test_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    test_data, label="label", weight="sample_weight"
)
# Out:
# 2026-08-15 05:20:48.472932: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:984] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2026-08-15 05:20:48.474488: W tensorflow/core/common_runtime/gpu/gpu_device.cc:2251] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...

# %%
import keras

# %%
# %%time

# Train a Random Forest model.
model = tfdf.keras.RandomForestModel()

# Add evaluation metrics
model.compile(
    metrics=["accuracy"]
)
model.fit(x=train_ds)

# # Train a Gradient Boosted Trees model.
# model = tfdf.keras.GradientBoostedTreesModel(num_trees=1500)
# model.fit(train_ds)
# Out:
# Use /tmp/tmpcr_cybyr as temporary training directory
# Reading training dataset...
# Training dataset read in 0:00:02.655868. Found 507 examples.
# Training model...
# Model trained in 0:00:00.039917
# Compiling model...
# [INFO 26-08-15 05:20:51.3560 UTC kernel.cc:1233] Loading model from path /tmp/tmpcr_cybyr/model/ with prefix dae5dfec227044de
# [INFO 26-08-15 05:20:51.3605 UTC decision_forest.cc:734] Model loaded with 300 root(s), 3286 node(s), and 24 input feature(s).
# [INFO 26-08-15 05:20:51.3605 UTC abstract_model.cc:1362] Engine "RandomForestOptPred" built
# [INFO 26-08-15 05:20:51.3605 UTC kernel.cc:1061] Use fast generic engine
# Model compiled.
# CPU times: user 5.56 s, sys: 58.3 ms, total: 5.62 s
# Wall time: 5.94 s

# %%
# Evaluate the model
evaluate = model.evaluate(val_ds, return_dict=True)
print()

for name, value in evaluate.items():
    print(f"{name}: {value:.4f}")
# Out:
# WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 1/1 [==============================] - ETA: 0s - loss: 0.0000e+00 - accuracy: 0.9722
# 1/1 [==============================] - 3s 3s/step - loss: 0.0000e+00 - accuracy: 0.9722
# loss: 0.0000
# accuracy: 0.9722

# %%
# Model Summary
model.summary()
# Out:
# Model: "random_forest_model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
# =================================================================
# Total params: 1 (1.00 Byte)
# Trainable params: 0 (0.00 Byte)
# Non-trainable params: 1 (1.00 Byte)
# _________________________________________________________________
# Type: "RANDOM_FOREST"
# Task: CLASSIFICATION
# Label: "__LABEL"
#
# Input Features (24):
# 	Autocorrelation
# 	ClusterProminence
# 	ClusterShade
# 	ClusterTendency
# 	Contrast
# 	Correlation
# 	DifferenceAverage
# 	DifferenceEntropy
# 	DifferenceVariance
# 	Id
# 	Idm
# 	Idmn
# 	Idn
# 	Imc1
# 	Imc2
# 	InverseVariance
# 	JointAverage
# 	JointEnergy
# 	JointEntropy
# 	MCC
# 	MaximumProbability
# 	SumAverage
# 	SumEntropy
# 	SumSquares
#
# Trained with weights
#
# Variable Importance: INV_MEAN_MIN_DEPTH:
#     1.    "Autocorrelation"  0.328445 ################
#     2.       "JointAverage"  0.322452 ##############
#     3.         "SumAverage"  0.318078 #############
#     4.         "SumEntropy"  0.312080 ############
#     5.               "Imc2"  0.302924 #########
#     6.        "Correlation"  0.285804 #####
#     7.                "MCC"  0.282102 #####
#     8.               "Imc1"  0.277433 ###
#     9.        "JointEnergy"  0.272200 ##
#    10.    "ClusterTendency"  0.271985 ##
#    11. "MaximumProbability"  0.271849 ##
#    12.       "JointEntropy"  0.268988 #
#    13.         "SumSquares"  0.267737 #
#    14.  "ClusterProminence"  0.266244 #
#    15.       "ClusterShade"  0.264887 #
#    16. "DifferenceVariance"  0.264845 #
#    17.                 "Id"  0.264210
#    18.           "Contrast"  0.262338
#    19.  "DifferenceEntropy"  0.261749
#    20.                "Idm"  0.261551
#    21.    "InverseVariance"  0.261236
#    22.               "Idmn"  0.260729
#    23.  "DifferenceAverage"  0.260698
#    24.                "Idn"  0.260557
#
# Variable Importance: NUM_AS_ROOT:
#     1.      "JointAverage" 62.000000 ################
#     2.   "Autocorrelation" 56.000000 ##############
#     3.        "SumAverage" 53.000000 #############
#     4.        "SumEntropy" 42.000000 ##########
#     5.              "Imc2" 29.000000 #######
#     6.       "Correlation" 15.000000 ###
#     7.              "Imc1" 10.000000 ##
#     8.               "MCC"  8.000000 #
#     9.   "ClusterTendency"  7.000000 #
#    10.        "SumSquares"  6.000000 #
#    11. "ClusterProminence"  4.000000
#    12.       "JointEnergy"  4.000000
#    13.      "JointEntropy"  3.000000
#    14.                "Id"  1.000000
#
# Variable Importance: NUM_NODES:
#     1.    "Autocorrelation" 173.000000 ################
#     2.       "JointAverage" 171.000000 ###############
#     3.         "SumAverage" 149.000000 #############
#     4.               "Imc2" 136.000000 ############
#     5.         "SumEntropy" 130.000000 ###########
#     6.        "Correlation" 78.000000 ######
#     7.                "MCC" 78.000000 ######
#     8.               "Imc1" 75.000000 ######
#     9.    "ClusterTendency" 53.000000 ####
#    10.       "JointEntropy" 49.000000 ###
#    11. "MaximumProbability" 49.000000 ###
#    12.       "ClusterShade" 47.000000 ###
#    13.        "JointEnergy" 42.000000 ##
#    14. "DifferenceVariance" 37.000000 ##
#    15.         "SumSquares" 33.000000 ##
#    16.           "Contrast" 32.000000 #
#    17.  "ClusterProminence" 28.000000 #
#    18.                "Idm" 24.000000 #
#    19.  "DifferenceEntropy" 23.000000 #
#    20.                 "Id" 21.000000
#    21.    "InverseVariance" 21.000000
#    22.               "Idmn" 17.000000
#    23.  "DifferenceAverage" 14.000000
#    24.                "Idn" 13.000000
#
# Variable Importance: SUM_SCORE:
#     1.       "JointAverage" 18990.144529 ################
#     2.    "Autocorrelation" 18476.076450 ###############
#     3.         "SumAverage" 16678.299806 ##############
#     4.         "SumEntropy" 12147.124150 ##########
#     5.               "Imc2" 9603.868082 ########
#     6.        "Correlation" 4214.042784 ###
#     7.                "MCC" 3158.049559 ##
#     8.               "Imc1" 2870.752834 ##
#     9.        "JointEnergy" 2345.132016 #
#    10.       "JointEntropy" 2043.880573 #
#    11.    "ClusterTendency" 2021.676921 #
#    12. "MaximumProbability" 1609.945379 #
#    13.         "SumSquares" 1488.242744 #
#    14.  "ClusterProminence" 1223.610089
#    15.       "ClusterShade" 964.841779
#    16.                 "Id" 749.274035
#    17.                "Idm" 622.095548
#    18. "DifferenceVariance" 382.001213
#    19.  "DifferenceEntropy" 373.128642
#    20.    "InverseVariance" 301.829190
#    21.           "Contrast" 254.532347
#    22.                "Idn" 197.972886
#    23.               "Idmn" 113.791901
#    24.  "DifferenceAverage" 109.032622
#
#
#
# Winner takes all: true
# Out-of-bag evaluation: accuracy:0.921759 logloss:0.16543
# Number of trees: 300
# Total number of nodes: 3286
#
# Number of nodes by tree:
# Count: 300 Average: 10.9533 StdDev: 2.94581
# Min: 5 Max: 23 Ignored: 0
# ----------------------------------------------
# [  5,  6)  4   1.33%   1.33%
# [  6,  7)  0   0.00%   1.33%
# [  7,  8) 42  14.00%  15.33% ####
# [  8,  9)  0   0.00%  15.33%
# [  9, 10) 68  22.67%  38.00% #######
# [ 10, 11)  0   0.00%  38.00%
# [ 11, 12) 99  33.00%  71.00% ##########
# [ 12, 13)  0   0.00%  71.00%
# [ 13, 14) 44  14.67%  85.67% ####
# [ 14, 15)  0   0.00%  85.67%
# [ 15, 16) 25   8.33%  94.00% ###
# [ 16, 17)  0   0.00%  94.00%
# [ 17, 18) 13   4.33%  98.33% #
# [ 18, 19)  0   0.00%  98.33%
# [ 19, 20)  2   0.67%  99.00%
# [ 20, 21)  0   0.00%  99.00%
# [ 21, 22)  2   0.67%  99.67%
# [ 22, 23)  0   0.00%  99.67%
# [ 23, 23]  1   0.33% 100.00%
#
# Depth by leafs:
# Count: 1793 Average: 3.00725 StdDev: 1.24314
# Min: 1 Max: 8 Ignored: 0
# ----------------------------------------------
# [ 1, 2) 111   6.19%   6.19% ##
# [ 2, 3) 595  33.18%  39.38% ##########
# [ 3, 4) 574  32.01%  71.39% ##########
# [ 4, 5) 300  16.73%  88.12% #####
# [ 5, 6) 135   7.53%  95.65% ##
# [ 6, 7)  56   3.12%  98.77% #
# [ 7, 8)  18   1.00%  99.78%
# [ 8, 8]   4   0.22% 100.00%
#
# Number of training obs by leaf:
# Count: 1793 Average: 84.8299 StdDev: 146.438
# Min: 5 Max: 491 Ignored: 0
# ----------------------------------------------
# [   5,  29) 1235  68.88%  68.88% ##########
# [  29,  53)  108   6.02%  74.90% #
# [  53,  78)   53   2.96%  77.86%
# [  78, 102)   34   1.90%  79.75%
# [ 102, 126)   27   1.51%  81.26%
# [ 126, 151)   15   0.84%  82.10%
# [ 151, 175)   10   0.56%  82.65%
# [ 175, 199)    6   0.33%  82.99%
# [ 199, 224)    3   0.17%  83.16%
# [ 224, 248)    8   0.45%  83.60%
# [ 248, 272)   10   0.56%  84.16%
# [ 272, 297)   15   0.84%  85.00%
# [ 297, 321)   31   1.73%  86.73%
# [ 321, 345)   11   0.61%  87.34%
# [ 345, 370)   18   1.00%  88.34%
# [ 370, 394)   28   1.56%  89.91%
# [ 394, 418)   21   1.17%  91.08%
# [ 418, 443)   60   3.35%  94.42%
# [ 443, 467)   46   2.57%  96.99%
# [ 467, 491]   54   3.01% 100.00%
#
# Attribute in nodes:
# 	173 : Autocorrelation [NUMERICAL]
# 	171 : JointAverage [NUMERICAL]
# 	149 : SumAverage [NUMERICAL]
# 	136 : Imc2 [NUMERICAL]
# 	130 : SumEntropy [NUMERICAL]
# 	78 : MCC [NUMERICAL]
# 	78 : Correlation [NUMERICAL]
# 	75 : Imc1 [NUMERICAL]
# 	53 : ClusterTendency [NUMERICAL]
# 	49 : MaximumProbability [NUMERICAL]
# 	49 : JointEntropy [NUMERICAL]
# 	47 : ClusterShade [NUMERICAL]
# 	42 : JointEnergy [NUMERICAL]
# 	37 : DifferenceVariance [NUMERICAL]
# 	33 : SumSquares [NUMERICAL]
# 	32 : Contrast [NUMERICAL]
# 	28 : ClusterProminence [NUMERICAL]
# 	24 : Idm [NUMERICAL]
# 	23 : DifferenceEntropy [NUMERICAL]
# 	21 : InverseVariance [NUMERICAL]
# 	21 : Id [NUMERICAL]
# 	17 : Idmn [NUMERICAL]
# 	14 : DifferenceAverage [NUMERICAL]
# 	13 : Idn [NUMERICAL]
#
# Attribute in nodes with depth <= 0:
# 	62 : JointAverage [NUMERICAL]
# 	56 : Autocorrelation [NUMERICAL]
# 	53 : SumAverage [NUMERICAL]
# 	42 : SumEntropy [NUMERICAL]
# 	29 : Imc2 [NUMERICAL]
# 	15 : Correlation [NUMERICAL]
# 	10 : Imc1 [NUMERICAL]
# 	8 : MCC [NUMERICAL]
# 	7 : ClusterTendency [NUMERICAL]
# 	6 : SumSquares [NUMERICAL]
# 	4 : JointEnergy [NUMERICAL]
# 	4 : ClusterProminence [NUMERICAL]
# 	3 : JointEntropy [NUMERICAL]
# 	1 : Id [NUMERICAL]
#
# Attribute in nodes with depth <= 1:
# 	103 : JointAverage [NUMERICAL]
# 	94 : SumEntropy [NUMERICAL]
# 	94 : Autocorrelation [NUMERICAL]
# 	89 : Imc2 [NUMERICAL]
# 	88 : SumAverage [NUMERICAL]
# 	57 : MCC [NUMERICAL]
# 	53 : Correlation [NUMERICAL]
# 	35 : Imc1 [NUMERICAL]
# 	34 : ClusterTendency [NUMERICAL]
# 	24 : JointEnergy [NUMERICAL]
# 	23 : JointEntropy [NUMERICAL]
# 	16 : ClusterProminence [NUMERICAL]
# 	14 : SumSquares [NUMERICAL]
# 	13 : MaximumProbability [NUMERICAL]
# 	9 : ClusterShade [NUMERICAL]
# 	7 : Id [NUMERICAL]
# 	7 : DifferenceEntropy [NUMERICAL]
# 	6 : Idm [NUMERICAL]
# 	6 : DifferenceVariance [NUMERICAL]
# 	4 : Idmn [NUMERICAL]
# 	4 : Contrast [NUMERICAL]
# 	3 : InverseVariance [NUMERICAL]
# 	3 : Idn [NUMERICAL]
# 	3 : DifferenceAverage [NUMERICAL]
#
# Attribute in nodes with depth <= 2:
# 	139 : JointAverage [NUMERICAL]
# 	137 : Autocorrelation [NUMERICAL]
# 	118 : Imc2 [NUMERICAL]
# 	117 : SumEntropy [NUMERICAL]
# 	117 : SumAverage [NUMERICAL]
# 	73 : MCC [NUMERICAL]
# 	66 : Correlation [NUMERICAL]
# 	58 : Imc1 [NUMERICAL]
# 	39 : ClusterTendency [NUMERICAL]
# 	38 : JointEntropy [NUMERICAL]
# 	37 : MaximumProbability [NUMERICAL]
# 	34 : JointEnergy [NUMERICAL]
# 	28 : ClusterShade [NUMERICAL]
# 	23 : ClusterProminence [NUMERICAL]
# 	21 : SumSquares [NUMERICAL]
# 	21 : Contrast [NUMERICAL]
# 	20 : DifferenceVariance [NUMERICAL]
# 	18 : Idm [NUMERICAL]
# 	17 : Id [NUMERICAL]
# 	14 : InverseVariance [NUMERICAL]
# 	11 : Idmn [NUMERICAL]
# 	11 : DifferenceEntropy [NUMERICAL]
# 	9 : DifferenceAverage [NUMERICAL]
# 	6 : Idn [NUMERICAL]
#
# Attribute in nodes with depth <= 3:
# 	161 : Autocorrelation [NUMERICAL]
# 	158 : JointAverage [NUMERICAL]
# 	133 : Imc2 [NUMERICAL]
# 	131 : SumAverage [NUMERICAL]
# 	124 : SumEntropy [NUMERICAL]
# 	78 : MCC [NUMERICAL]
# 	75 : Correlation [NUMERICAL]
# 	67 : Imc1 [NUMERICAL]
# 	47 : MaximumProbability [NUMERICAL]
# 	43 : ClusterTendency [NUMERICAL]
# 	41 : JointEntropy [NUMERICAL]
# 	40 : ClusterShade [NUMERICAL]
# 	38 : JointEnergy [NUMERICAL]
# 	32 : DifferenceVariance [NUMERICAL]
# 	31 : SumSquares [NUMERICAL]
# 	25 : Contrast [NUMERICAL]
# 	25 : ClusterProminence [NUMERICAL]
# 	22 : Idm [NUMERICAL]
# 	21 : Id [NUMERICAL]
# 	18 : InverseVariance [NUMERICAL]
# 	18 : DifferenceEntropy [NUMERICAL]
# 	15 : Idmn [NUMERICAL]
# 	11 : DifferenceAverage [NUMERICAL]
# 	10 : Idn [NUMERICAL]
#
# Attribute in nodes with depth <= 5:
# 	173 : Autocorrelation [NUMERICAL]
# 	170 : JointAverage [NUMERICAL]
# 	148 : SumAverage [NUMERICAL]
# 	136 : Imc2 [NUMERICAL]
# 	130 : SumEntropy [NUMERICAL]
# 	78 : MCC [NUMERICAL]
# 	78 : Correlation [NUMERICAL]
# 	75 : Imc1 [NUMERICAL]
# 	52 : ClusterTendency [NUMERICAL]
# 	48 : MaximumProbability [NUMERICAL]
# 	48 : JointEntropy [NUMERICAL]
# 	45 : ClusterShade [NUMERICAL]
# 	42 : JointEnergy [NUMERICAL]
# 	35 : DifferenceVariance [NUMERICAL]
# 	32 : SumSquares [NUMERICAL]
# 	32 : Contrast [NUMERICAL]
# 	27 : ClusterProminence [NUMERICAL]
# 	24 : Idm [NUMERICAL]
# 	22 : DifferenceEntropy [NUMERICAL]
# 	21 : InverseVariance [NUMERICAL]
# 	21 : Id [NUMERICAL]
# 	17 : Idmn [NUMERICAL]
# 	14 : DifferenceAverage [NUMERICAL]
# 	13 : Idn [NUMERICAL]
#
# Condition type in nodes:
# 	1493 : HigherCondition
# Condition type in nodes with depth <= 0:
# 	300 : HigherCondition
# Condition type in nodes with depth <= 1:
# 	789 : HigherCondition
# Condition type in nodes with depth <= 2:
# 	1172 : HigherCondition
# Condition type in nodes with depth <= 3:
# 	1364 : HigherCondition
# Condition type in nodes with depth <= 5:
# 	1481 : HigherCondition
# Node format: NOT_SET
#
# Training OOB:
# 	trees: 1, Out-of-bag evaluation: accuracy:0.994915 logloss:0.183273
# 	trees: 12, Out-of-bag evaluation: accuracy:0.916098 logloss:2.30956
# 	trees: 22, Out-of-bag evaluation: accuracy:0.920718 logloss:0.159658
# 	trees: 32, Out-of-bag evaluation: accuracy:0.904282 logloss:0.182292
# 	trees: 42, Out-of-bag evaluation: accuracy:0.904282 logloss:0.183715
# 	trees: 52, Out-of-bag evaluation: accuracy:0.904282 logloss:0.193326
# 	trees: 62, Out-of-bag evaluation: accuracy:0.885764 logloss:0.200379
# 	trees: 72, Out-of-bag evaluation: accuracy:0.904282 logloss:0.19442
# 	trees: 82, Out-of-bag evaluation: accuracy:0.922801 logloss:0.175464
# 	trees: 94, Out-of-bag evaluation: accuracy:0.904282 logloss:0.17427
# 	trees: 104, Out-of-bag evaluation: accuracy:0.922801 logloss:0.177894
# 	trees: 114, Out-of-bag evaluation: accuracy:0.922801 logloss:0.177559
# 	trees: 124, Out-of-bag evaluation: accuracy:0.922801 logloss:0.179083
# 	trees: 134, Out-of-bag evaluation: accuracy:0.920718 logloss:0.17814
# 	trees: 144, Out-of-bag evaluation: accuracy:0.921759 logloss:0.174294
# 	trees: 154, Out-of-bag evaluation: accuracy:0.921759 logloss:0.173076
# 	trees: 164, Out-of-bag evaluation: accuracy:0.920718 logloss:0.171359
# 	trees: 175, Out-of-bag evaluation: accuracy:0.921759 logloss:0.168234
# 	trees: 185, Out-of-bag evaluation: accuracy:0.921759 logloss:0.169946
# 	trees: 196, Out-of-bag evaluation: accuracy:0.921759 logloss:0.166953
# 	trees: 206, Out-of-bag evaluation: accuracy:0.921759 logloss:0.169685
# 	trees: 217, Out-of-bag evaluation: accuracy:0.922801 logloss:0.164909
# 	trees: 227, Out-of-bag evaluation: accuracy:0.922801 logloss:0.16337
# 	trees: 238, Out-of-bag evaluation: accuracy:0.922801 logloss:0.165482
# 	trees: 250, Out-of-bag evaluation: accuracy:0.921759 logloss:0.166942
# 	trees: 260, Out-of-bag evaluation: accuracy:0.921759 logloss:0.166538
# 	trees: 270, Out-of-bag evaluation: accuracy:0.921759 logloss:0.166038
# 	trees: 281, Out-of-bag evaluation: accuracy:0.921759 logloss:0.165365
# 	trees: 291, Out-of-bag evaluation: accuracy:0.921759 logloss:0.165228
# 	trees: 300, Out-of-bag evaluation: accuracy:0.921759 logloss:0.16543

# %%
# Model features
model.make_inspector().features()
# Out:
# ["Autocorrelation" (1; #0),
#  "ClusterProminence" (1; #1),
#  "ClusterShade" (1; #2),
#  "ClusterTendency" (1; #3),
#  "Contrast" (1; #4),
#  "Correlation" (1; #5),
#  "DifferenceAverage" (1; #6),
#  "DifferenceEntropy" (1; #7),
#  "DifferenceVariance" (1; #8),
#  "Id" (1; #9),
#  "Idm" (1; #10),
#  "Idmn" (1; #11),
#  "Idn" (1; #12),
#  "Imc1" (1; #13),
#  "Imc2" (1; #14),
#  "InverseVariance" (1; #15),
#  "JointAverage" (1; #16),
#  "JointEnergy" (1; #17),
#  "JointEntropy" (1; #18),
#  "MCC" (1; #19),
#  "MaximumProbability" (1; #20),
#  "SumAverage" (1; #21),
#  "SumEntropy" (1; #22),
#  "SumSquares" (1; #23)]

# %%
# Feature importance
model.make_inspector().variable_importances()
# Out:
# {'INV_MEAN_MIN_DEPTH': [("Autocorrelation" (1; #0), 0.328445177025868),
#   ("JointAverage" (1; #16), 0.322452025082859),
#   ("SumAverage" (1; #21), 0.31807771515245575),
#   ("SumEntropy" (1; #22), 0.31208010055914354),
#   ("Imc2" (1; #14), 0.30292359517270345),
#   ("Correlation" (1; #5), 0.2858037798271611),
#   ("MCC" (1; #19), 0.2821017817529541),
#   ("Imc1" (1; #13), 0.27743284013496394),
#   ("JointEnergy" (1; #17), 0.2721997629413705),
#   ("ClusterTendency" (1; #3), 0.27198541404628057),
#   ("MaximumProbability" (1; #20), 0.2718493878550665),
#   ("JointEntropy" (1; #18), 0.2689877588898013),
#   ("SumSquares" (1; #23), 0.2677373499172948),
#   ("ClusterProminence" (1; #1), 0.2662440741003745),
#   ("ClusterShade" (1; #2), 0.2648867736453332),
#   ("DifferenceVariance" (1; #8), 0.264844551439605),
#   ("Id" (1; #9), 0.264210042790208),
#   ("Contrast" (1; #4), 0.26233797648838475),
#   ("DifferenceEntropy" (1; #7), 0.26174948622692845),
#   ("Idm" (1; #10), 0.2615505335854191),
#   ("InverseVariance" (1; #15), 0.2612361956885284),
#   ("Idmn" (1; #11), 0.26072916504024474),
#   ("DifferenceAverage" (1; #6), 0.2606979582797998),
#   ("Idn" (1; #12), 0.2605573263559782)],
#  'SUM_SCORE': [("JointAverage" (1; #16), 18990.14452872893),
#   ("Autocorrelation" (1; #0), 18476.076450302862),
#   ("SumAverage" (1; #21), 16678.29980636173),
#   ("SumEntropy" (1; #22), 12147.124149769776),
#   ("Imc2" (1; #14), 9603.868082161856),
#   ("Correlation" (1; #5), 4214.042783597136),
#   ("MCC" (1; #19), 3158.0495585125286),
#   ("Imc1" (1; #13), 2870.7528339489163),
#   ("JointEnergy" (1; #17), 2345.132016012099),
#   ("JointEntropy" (1; #18), 2043.8805728318255),
#   ("ClusterTendency" (1; #3), 2021.6769208738067),
#   ("MaximumProbability" (1; #20), 1609.945379347357),
#   ("SumSquares" (1; #23), 1488.2427441317054),
#   ("ClusterProminence" (1; #1), 1223.6100887543603),
#   ("ClusterShade" (1; #2), 964.8417790484788),
#   ("Id" (1; #9), 749.274034870014),
#   ("Idm" (1; #10), 622.0955484933256),
#   ("DifferenceVariance" (1; #8), 382.0012133237034),
#   ("DifferenceEntropy" (1; #7), 373.1286420906416),
#   ("InverseVariance" (1; #15), 301.8291898925121),
#   ("Contrast" (1; #4), 254.53234662549872),
#   ("Idn" (1; #12), 197.97288594497172),
#   ("Idmn" (1; #11), 113.79190089901932),
#   ("DifferenceAverage" (1; #6), 109.03262177068089)],
#  'NUM_AS_ROOT': [("JointAverage" (1; #16), 62.0),
#   ("Autocorrelation" (1; #0), 56.0),
#   ("SumAverage" (1; #21), 53.0),
#   ("SumEntropy" (1; #22), 42.0),
#   ("Imc2" (1; #14), 29.0),
#   ("Correlation" (1; #5), 15.0),
#   ("Imc1" (1; #13), 10.0),
#   ("MCC" (1; #19), 8.0),
#   ("ClusterTendency" (1; #3), 7.0),
#   ("SumSquares" (1; #23), 6.0),
#   ("ClusterProminence" (1; #1), 4.0),
#   ("JointEnergy" (1; #17), 4.0),
#   ("JointEntropy" (1; #18), 3.0),
#   ("Id" (1; #9), 1.0)],
#  'NUM_NODES': [("Autocorrelation" (1; #0), 173.0),
#   ("JointAverage" (1; #16), 171.0),
#   ("SumAverage" (1; #21), 149.0),
#   ("Imc2" (1; #14), 136.0),
#   ("SumEntropy" (1; #22), 130.0),
#   ("Correlation" (1; #5), 78.0),
#   ("MCC" (1; #19), 78.0),
#   ("Imc1" (1; #13), 75.0),
#   ("ClusterTendency" (1; #3), 53.0),
#   ("JointEntropy" (1; #18), 49.0),
#   ("MaximumProbability" (1; #20), 49.0),
#   ("ClusterShade" (1; #2), 47.0),
#   ("JointEnergy" (1; #17), 42.0),
#   ("DifferenceVariance" (1; #8), 37.0),
#   ("SumSquares" (1; #23), 33.0),
#   ("Contrast" (1; #4), 32.0),
#   ("ClusterProminence" (1; #1), 28.0),
#   ("Idm" (1; #10), 24.0),
#   ("DifferenceEntropy" (1; #7), 23.0),
#   ("Id" (1; #9), 21.0),
#   ("InverseVariance" (1; #15), 21.0),
#   ("Idmn" (1; #11), 17.0),
#   ("DifferenceAverage" (1; #6), 14.0),
#   ("Idn" (1; #12), 13.0)]}

# %%
# Model self evaluation
model.make_inspector().evaluation()
# Out:
# Evaluation(num_examples=507, accuracy=0.9217592568923161, loss=0.16542980106989166, rmse=None, ndcg=None, aucs=None, auuc=None, qini=None)

# %%
logs = model.make_inspector().training_logs()

plt.figure(figsize=(12, 4))
plt.subplot(1, 2, 1)
plt.plot([log.num_trees for log in logs], [log.evaluation.accuracy for log in logs])
plt.xlabel("Number of trees")
plt.ylabel("Accuracy (out-of-bag)")
plt.subplot(1, 2, 2)
plt.plot([log.num_trees for log in logs], [log.evaluation.loss for log in logs])
plt.xlabel("Number of trees")
plt.ylabel("Logloss (out-of-bag)")
plt.show()

# %% [markdown]
# Calculate the score of our hold-out validation dataset

# %%
predictions = model.predict(val_ds)
y_true      = validation_data["label"]

from sklearn.metrics import roc_auc_score
ROC_AUC = roc_auc_score(y_true, predictions)
print("The ROC AUC score is %.5f" % ROC_AUC )
# Out:
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 64ms/step
# The ROC AUC score is 0.98551

# %%
# Compute binary classification metrics with sklearn
import numpy as np
from sklearn.metrics import (
    accuracy_score,
    precision_score,
    recall_score,
    f1_score,
    roc_auc_score,
    average_precision_score,
    confusion_matrix,
    classification_report,
    matthews_corrcoef,
    log_loss,
    brier_score_loss,
)

# Get predictions (probabilities or class labels)
preds = model.predict(test_ds)
# If model outputs probabilities, convert to labels by threshold 0.5
if preds.ndim == 2:
    # For TFDF classification, preds may be class probabilities with shape (N, 2)
    if preds.shape[1] == 2:
        pos_probs = preds[:, 1]
    else:
        # If single-probability column (positive class)
        pos_probs = preds[:, -1]
    y_pred = (pos_probs >= 0.5).astype(int)
else:
    # Already class labels
    y_pred = preds.astype(int)
    pos_probs = None

# Ground truth labels (must be 0/1 integers)
y_true = test_data["label"].astype(int).to_numpy()

# Core metrics
metrics = {}
metrics["accuracy"] = accuracy_score(y_true, y_pred)
metrics["precision"] = precision_score(y_true, y_pred, zero_division=0)
metrics["recall"] = recall_score(y_true, y_pred, zero_division=0)
metrics["f1"] = f1_score(y_true, y_pred, zero_division=0)
metrics["mcc"] = matthews_corrcoef(y_true, y_pred)

# Probabilistic metrics (only if we have probabilities)
if pos_probs is not None:
    metrics["roc_auc"] = roc_auc_score(y_true, pos_probs)
    metrics["pr_auc"] = average_precision_score(y_true, pos_probs)
    metrics["log_loss"] = log_loss(y_true, pos_probs, labels=[0,1])
    metrics["brier_score"] = brier_score_loss(y_true, pos_probs)

# Confusion matrix and detailed report
cm = confusion_matrix(y_true, y_pred, labels=[0,1])
report = classification_report(y_true, y_pred, digits=4)

print("Sklearn binary metrics:")
for k, v in metrics.items():
    print(f"{k}: {v:.4f}")
print("\nConfusion matrix:\n", cm)
print("\nClassification report:\n", report)
# Out:
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 76ms/step
# Sklearn binary metrics:
# accuracy: 0.9863
# precision: 0.9000
# recall: 0.9000
# f1: 0.9000
# mcc: 0.8926
# roc_auc: 0.9978
# pr_auc: 0.9709
# log_loss: 0.0336
# brier_score: 0.0091
#
# Confusion matrix:
#  [[135   1]
#  [  1   9]]
#
# Classification report:
#                precision    recall  f1-score   support
#
#            0     0.9926    0.9926    0.9926       136
#            1     0.9000    0.9000    0.9000        10
#
#     accuracy                         0.9863       146
#    macro avg     0.9463    0.9463    0.9463       146
# weighted avg     0.9863    0.9863    0.9863       146
