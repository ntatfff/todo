# %%
# Import packages and modules
import numpy  as np
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow_decision_forests as tfdf

from sklearn.model_selection import train_test_split
# Out:
# 2026-08-15 05:21:05.726904: I tensorflow/core/util/port.cc:113] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2026-08-15 05:21:06.085413: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2026-08-15 05:21:11.448002: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
# Check the version of TensorFlow Decision Forests
print("Found TensorFlow Decision Forests v" + tfdf.__version__)
# Out:
# Found TensorFlow Decision Forests v1.9.1

# %%
datasetPath = 'dataset/firstorder/kernel5/dataset.csv'

# %%
# Parameters
datasetPath = "dataset/gldm/kernel6/1.dataset.csv"

# %%
# train/validation/test = 70/10/20
dataset = pd.read_csv(datasetPath)

train_data, temp_data = train_test_split(dataset, test_size=0.3, random_state=42)
validation_data, test_data = train_test_split(temp_data, test_size=2/3, random_state=42)

# %%
from sklearn.utils.class_weight import compute_class_weight

# tinh class weight tren tap train
classes = np.array([0, 1])
weights = compute_class_weight(class_weight="balanced", classes=classes, y=train_data["label"])
class_weight = {0: weights[0], 1: weights[1]}

# gan sample_weight cho tung dong
train_data["sample_weight"] = train_data["label"].map(class_weight)
validation_data["sample_weight"] = validation_data["label"].map(class_weight)
test_data["sample_weight"] = test_data["label"].map(class_weight)

# Convert the dataset into a TensorFlow dataset.
train_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    train_data, label="label", weight="sample_weight"
)         
val_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    validation_data, label="label", weight="sample_weight"
)
test_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    test_data, label="label", weight="sample_weight"
)
# Out:
# 2026-08-15 05:21:24.484094: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:984] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2026-08-15 05:21:24.485737: W tensorflow/core/common_runtime/gpu/gpu_device.cc:2251] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...

# %%
import keras

# %%
# %%time

# Train a Random Forest model.
model = tfdf.keras.RandomForestModel()

# Add evaluation metrics
model.compile(
    metrics=["accuracy"]
)
model.fit(x=train_ds)

# # Train a Gradient Boosted Trees model.
# model = tfdf.keras.GradientBoostedTreesModel(num_trees=1500)
# model.fit(train_ds)
# Out:
# Use /tmp/tmpbe9ibpty as temporary training directory
# Reading training dataset...
# Training dataset read in 0:00:02.593993. Found 507 examples.
# Training model...
# Model trained in 0:00:00.040444
# Compiling model...
# [INFO 26-08-15 05:21:27.2789 UTC kernel.cc:1233] Loading model from path /tmp/tmpbe9ibpty/model/ with prefix 13e04799fc484761
# [INFO 26-08-15 05:21:27.2837 UTC decision_forest.cc:734] Model loaded with 300 root(s), 3398 node(s), and 14 input feature(s).
# [INFO 26-08-15 05:21:27.2837 UTC abstract_model.cc:1362] Engine "RandomForestOptPred" built
# [INFO 26-08-15 05:21:27.2837 UTC kernel.cc:1061] Use fast generic engine
# Model compiled.
# CPU times: user 5.49 s, sys: 42.9 ms, total: 5.53 s
# Wall time: 5.81 s

# %%
# Evaluate the model
evaluate = model.evaluate(val_ds, return_dict=True)
print()

for name, value in evaluate.items():
    print(f"{name}: {value:.4f}")
# Out:
# WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 1/1 [==============================] - ETA: 0s - loss: 0.0000e+00 - accuracy: 0.9861
# 1/1 [==============================] - 3s 3s/step - loss: 0.0000e+00 - accuracy: 0.9861
# loss: 0.0000
# accuracy: 0.9861

# %%
# Model Summary
model.summary()
# Out:
# Model: "random_forest_model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
# =================================================================
# Total params: 1 (1.00 Byte)
# Trainable params: 0 (0.00 Byte)
# Non-trainable params: 1 (1.00 Byte)
# _________________________________________________________________
# Type: "RANDOM_FOREST"
# Task: CLASSIFICATION
# Label: "__LABEL"
#
# Input Features (14):
# 	DependenceEntropy
# 	DependenceNonUniformity
# 	DependenceNonUniformityNormalized
# 	DependenceVariance
# 	GrayLevelNonUniformity
# 	GrayLevelVariance
# 	HighGrayLevelEmphasis
# 	LargeDependenceEmphasis
# 	LargeDependenceHighGrayLevelEmphasis
# 	LargeDependenceLowGrayLevelEmphasis
# 	LowGrayLevelEmphasis
# 	SmallDependenceEmphasis
# 	SmallDependenceHighGrayLevelEmphasis
# 	SmallDependenceLowGrayLevelEmphasis
#
# Trained with weights
#
# Variable Importance: INV_MEAN_MIN_DEPTH:
#     1.                "HighGrayLevelEmphasis"  0.375080 ################
#     2. "SmallDependenceHighGrayLevelEmphasis"  0.356665 #############
#     3.                 "LowGrayLevelEmphasis"  0.323167 ########
#     4.                    "DependenceEntropy"  0.310116 ######
#     5.  "LargeDependenceLowGrayLevelEmphasis"  0.288047 ###
#     6.               "GrayLevelNonUniformity"  0.281902 ###
#     7.  "SmallDependenceLowGrayLevelEmphasis"  0.279692 ##
#     8. "LargeDependenceHighGrayLevelEmphasis"  0.279178 ##
#     9.                    "GrayLevelVariance"  0.274349 #
#    10.              "SmallDependenceEmphasis"  0.266607
#    11.              "LargeDependenceEmphasis"  0.262324
#    12.              "DependenceNonUniformity"  0.261391
#    13.                   "DependenceVariance"  0.261034
#    14.    "DependenceNonUniformityNormalized"  0.260057
#
# Variable Importance: NUM_AS_ROOT:
#     1.                "HighGrayLevelEmphasis" 104.000000 ################
#     2. "SmallDependenceHighGrayLevelEmphasis" 84.000000 ############
#     3.                 "LowGrayLevelEmphasis" 52.000000 #######
#     4.  "LargeDependenceLowGrayLevelEmphasis" 26.000000 ###
#     5.                    "DependenceEntropy" 16.000000 ##
#     6. "LargeDependenceHighGrayLevelEmphasis"  9.000000 #
#     7.  "SmallDependenceLowGrayLevelEmphasis"  5.000000
#     8.               "GrayLevelNonUniformity"  2.000000
#     9.                    "GrayLevelVariance"  2.000000
#
# Variable Importance: NUM_NODES:
#     1.                "HighGrayLevelEmphasis" 233.000000 ################
#     2.                    "DependenceEntropy" 207.000000 #############
#     3. "SmallDependenceHighGrayLevelEmphasis" 183.000000 ############
#     4.               "GrayLevelNonUniformity" 182.000000 ###########
#     5.                 "LowGrayLevelEmphasis" 168.000000 ##########
#     6.  "SmallDependenceLowGrayLevelEmphasis" 106.000000 #####
#     7. "LargeDependenceHighGrayLevelEmphasis" 96.000000 #####
#     8.  "LargeDependenceLowGrayLevelEmphasis" 87.000000 ####
#     9.                    "GrayLevelVariance" 74.000000 ###
#    10.              "SmallDependenceEmphasis" 66.000000 ##
#    11.              "LargeDependenceEmphasis" 42.000000
#    12.                   "DependenceVariance" 41.000000
#    13.              "DependenceNonUniformity" 34.000000
#    14.    "DependenceNonUniformityNormalized" 30.000000
#
# Variable Importance: SUM_SCORE:
#     1.                "HighGrayLevelEmphasis" 31447.865017 ################
#     2. "SmallDependenceHighGrayLevelEmphasis" 25674.490975 #############
#     3.                 "LowGrayLevelEmphasis" 14276.766119 #######
#     4.                    "DependenceEntropy" 8376.396727 ####
#     5.  "LargeDependenceLowGrayLevelEmphasis" 7171.031143 ###
#     6.               "GrayLevelNonUniformity" 5812.964614 ##
#     7. "LargeDependenceHighGrayLevelEmphasis" 2438.413915 #
#     8.  "SmallDependenceLowGrayLevelEmphasis" 2100.324234
#     9.                    "GrayLevelVariance" 1353.257336
#    10.              "SmallDependenceEmphasis" 797.890833
#    11.              "LargeDependenceEmphasis" 797.866930
#    12.              "DependenceNonUniformity" 352.079157
#    13.    "DependenceNonUniformityNormalized" 346.175041
#    14.                   "DependenceVariance" 326.462097
#
#
#
# Winner takes all: true
# Out-of-bag evaluation: accuracy:0.936948 logloss:0.134769
# Number of trees: 300
# Total number of nodes: 3398
#
# Number of nodes by tree:
# Count: 300 Average: 11.3267 StdDev: 2.28909
# Min: 5 Max: 17 Ignored: 0
# ----------------------------------------------
# [  5,  6)  1   0.33%   0.33%
# [  6,  7)  0   0.00%   0.33%
# [  7,  8) 20   6.67%   7.00% ##
# [  8,  9)  0   0.00%   7.00%
# [  9, 10) 69  23.00%  30.00% ########
# [ 10, 11)  0   0.00%  30.00%
# [ 11, 12) 87  29.00%  59.00% ##########
# [ 12, 13)  0   0.00%  59.00%
# [ 13, 14) 88  29.33%  88.33% ##########
# [ 14, 15)  0   0.00%  88.33%
# [ 15, 16) 32  10.67%  99.00% ####
# [ 16, 17)  0   0.00%  99.00%
# [ 17, 17]  3   1.00% 100.00%
#
# Depth by leafs:
# Count: 1849 Average: 2.95836 StdDev: 1.05904
# Min: 1 Max: 7 Ignored: 0
# ----------------------------------------------
# [ 1, 2)  77   4.16%   4.16% #
# [ 2, 3) 611  33.04%  37.21% #########
# [ 3, 4) 664  35.91%  73.12% ##########
# [ 4, 5) 346  18.71%  91.83% #####
# [ 5, 6) 115   6.22%  98.05% ##
# [ 6, 7)  32   1.73%  99.78%
# [ 7, 7]   4   0.22% 100.00%
#
# Number of training obs by leaf:
# Count: 1849 Average: 82.2607 StdDev: 156.471
# Min: 5 Max: 478 Ignored: 0
# ----------------------------------------------
# [   5,  28) 1378  74.53%  74.53% ##########
# [  28,  52)  138   7.46%  81.99% #
# [  52,  76)    6   0.32%  82.31%
# [  76,  99)   10   0.54%  82.86%
# [  99, 123)    7   0.38%  83.23%
# [ 123, 147)    5   0.27%  83.50%
# [ 147, 170)    2   0.11%  83.61%
# [ 170, 194)    1   0.05%  83.67%
# [ 194, 218)    1   0.05%  83.72%
# [ 218, 242)    2   0.11%  83.83%
# [ 242, 265)    1   0.05%  83.88%
# [ 265, 289)    1   0.05%  83.94%
# [ 289, 313)    6   0.32%  84.26%
# [ 313, 336)    5   0.27%  84.53%
# [ 336, 360)    6   0.32%  84.86%
# [ 360, 384)    6   0.32%  85.18%
# [ 384, 407)   15   0.81%  85.99%
# [ 407, 431)   44   2.38%  88.37%
# [ 431, 455)  119   6.44%  94.81% #
# [ 455, 478]   96   5.19% 100.00% #
#
# Attribute in nodes:
# 	233 : HighGrayLevelEmphasis [NUMERICAL]
# 	207 : DependenceEntropy [NUMERICAL]
# 	183 : SmallDependenceHighGrayLevelEmphasis [NUMERICAL]
# 	182 : GrayLevelNonUniformity [NUMERICAL]
# 	168 : LowGrayLevelEmphasis [NUMERICAL]
# 	106 : SmallDependenceLowGrayLevelEmphasis [NUMERICAL]
# 	96 : LargeDependenceHighGrayLevelEmphasis [NUMERICAL]
# 	87 : LargeDependenceLowGrayLevelEmphasis [NUMERICAL]
# 	74 : GrayLevelVariance [NUMERICAL]
# 	66 : SmallDependenceEmphasis [NUMERICAL]
# 	42 : LargeDependenceEmphasis [NUMERICAL]
# 	41 : DependenceVariance [NUMERICAL]
# 	34 : DependenceNonUniformity [NUMERICAL]
# 	30 : DependenceNonUniformityNormalized [NUMERICAL]
#
# Attribute in nodes with depth <= 0:
# 	104 : HighGrayLevelEmphasis [NUMERICAL]
# 	84 : SmallDependenceHighGrayLevelEmphasis [NUMERICAL]
# 	52 : LowGrayLevelEmphasis [NUMERICAL]
# 	26 : LargeDependenceLowGrayLevelEmphasis [NUMERICAL]
# 	16 : DependenceEntropy [NUMERICAL]
# 	9 : LargeDependenceHighGrayLevelEmphasis [NUMERICAL]
# 	5 : SmallDependenceLowGrayLevelEmphasis [NUMERICAL]
# 	2 : GrayLevelVariance [NUMERICAL]
# 	2 : GrayLevelNonUniformity [NUMERICAL]
#
# Attribute in nodes with depth <= 1:
# 	172 : HighGrayLevelEmphasis [NUMERICAL]
# 	141 : SmallDependenceHighGrayLevelEmphasis [NUMERICAL]
# 	123 : DependenceEntropy [NUMERICAL]
# 	96 : LowGrayLevelEmphasis [NUMERICAL]
# 	82 : GrayLevelNonUniformity [NUMERICAL]
# 	50 : LargeDependenceLowGrayLevelEmphasis [NUMERICAL]
# 	38 : LargeDependenceHighGrayLevelEmphasis [NUMERICAL]
# 	37 : SmallDependenceLowGrayLevelEmphasis [NUMERICAL]
# 	34 : GrayLevelVariance [NUMERICAL]
# 	19 : LargeDependenceEmphasis [NUMERICAL]
# 	16 : SmallDependenceEmphasis [NUMERICAL]
# 	7 : DependenceNonUniformity [NUMERICAL]
# 	6 : DependenceNonUniformityNormalized [NUMERICAL]
# 	2 : DependenceVariance [NUMERICAL]
#
# Attribute in nodes with depth <= 2:
# 	215 : HighGrayLevelEmphasis [NUMERICAL]
# 	173 : DependenceEntropy [NUMERICAL]
# 	166 : SmallDependenceHighGrayLevelEmphasis [NUMERICAL]
# 	141 : LowGrayLevelEmphasis [NUMERICAL]
# 	136 : GrayLevelNonUniformity [NUMERICAL]
# 	84 : SmallDependenceLowGrayLevelEmphasis [NUMERICAL]
# 	72 : LargeDependenceHighGrayLevelEmphasis [NUMERICAL]
# 	70 : LargeDependenceLowGrayLevelEmphasis [NUMERICAL]
# 	56 : GrayLevelVariance [NUMERICAL]
# 	48 : SmallDependenceEmphasis [NUMERICAL]
# 	37 : LargeDependenceEmphasis [NUMERICAL]
# 	21 : DependenceNonUniformity [NUMERICAL]
# 	20 : DependenceNonUniformityNormalized [NUMERICAL]
# 	19 : DependenceVariance [NUMERICAL]
#
# Attribute in nodes with depth <= 3:
# 	229 : HighGrayLevelEmphasis [NUMERICAL]
# 	196 : DependenceEntropy [NUMERICAL]
# 	181 : SmallDependenceHighGrayLevelEmphasis [NUMERICAL]
# 	166 : GrayLevelNonUniformity [NUMERICAL]
# 	160 : LowGrayLevelEmphasis [NUMERICAL]
# 	103 : SmallDependenceLowGrayLevelEmphasis [NUMERICAL]
# 	91 : LargeDependenceHighGrayLevelEmphasis [NUMERICAL]
# 	80 : LargeDependenceLowGrayLevelEmphasis [NUMERICAL]
# 	67 : GrayLevelVariance [NUMERICAL]
# 	60 : SmallDependenceEmphasis [NUMERICAL]
# 	38 : LargeDependenceEmphasis [NUMERICAL]
# 	37 : DependenceVariance [NUMERICAL]
# 	30 : DependenceNonUniformity [NUMERICAL]
# 	26 : DependenceNonUniformityNormalized [NUMERICAL]
#
# Attribute in nodes with depth <= 5:
# 	233 : HighGrayLevelEmphasis [NUMERICAL]
# 	207 : DependenceEntropy [NUMERICAL]
# 	183 : SmallDependenceHighGrayLevelEmphasis [NUMERICAL]
# 	182 : GrayLevelNonUniformity [NUMERICAL]
# 	168 : LowGrayLevelEmphasis [NUMERICAL]
# 	105 : SmallDependenceLowGrayLevelEmphasis [NUMERICAL]
# 	96 : LargeDependenceHighGrayLevelEmphasis [NUMERICAL]
# 	87 : LargeDependenceLowGrayLevelEmphasis [NUMERICAL]
# 	74 : GrayLevelVariance [NUMERICAL]
# 	66 : SmallDependenceEmphasis [NUMERICAL]
# 	42 : LargeDependenceEmphasis [NUMERICAL]
# 	40 : DependenceVariance [NUMERICAL]
# 	34 : DependenceNonUniformity [NUMERICAL]
# 	30 : DependenceNonUniformityNormalized [NUMERICAL]
#
# Condition type in nodes:
# 	1549 : HigherCondition
# Condition type in nodes with depth <= 0:
# 	300 : HigherCondition
# Condition type in nodes with depth <= 1:
# 	823 : HigherCondition
# Condition type in nodes with depth <= 2:
# 	1258 : HigherCondition
# Condition type in nodes with depth <= 3:
# 	1464 : HigherCondition
# Condition type in nodes with depth <= 5:
# 	1547 : HigherCondition
# Node format: NOT_SET
#
# Training OOB:
# 	trees: 1, Out-of-bag evaluation: accuracy:0.906652 logloss:3.36459
# 	trees: 13, Out-of-bag evaluation: accuracy:0.918057 logloss:1.83061
# 	trees: 23, Out-of-bag evaluation: accuracy:0.935823 logloss:1.69666
# 	trees: 33, Out-of-bag evaluation: accuracy:0.921185 logloss:0.664565
# 	trees: 43, Out-of-bag evaluation: accuracy:0.922242 logloss:0.660414
# 	trees: 53, Out-of-bag evaluation: accuracy:0.922242 logloss:0.16162
# 	trees: 63, Out-of-bag evaluation: accuracy:0.922242 logloss:0.156887
# 	trees: 73, Out-of-bag evaluation: accuracy:0.922242 logloss:0.161228
# 	trees: 83, Out-of-bag evaluation: accuracy:0.922242 logloss:0.158505
# 	trees: 93, Out-of-bag evaluation: accuracy:0.936948 logloss:0.158531
# 	trees: 103, Out-of-bag evaluation: accuracy:0.936948 logloss:0.152582
# 	trees: 113, Out-of-bag evaluation: accuracy:0.935891 logloss:0.151789
# 	trees: 123, Out-of-bag evaluation: accuracy:0.935891 logloss:0.146645
# 	trees: 134, Out-of-bag evaluation: accuracy:0.936948 logloss:0.150095
# 	trees: 144, Out-of-bag evaluation: accuracy:0.936948 logloss:0.148987
# 	trees: 154, Out-of-bag evaluation: accuracy:0.936948 logloss:0.147167
# 	trees: 164, Out-of-bag evaluation: accuracy:0.936948 logloss:0.143613
# 	trees: 175, Out-of-bag evaluation: accuracy:0.936948 logloss:0.145104
# 	trees: 185, Out-of-bag evaluation: accuracy:0.936948 logloss:0.146525
# 	trees: 195, Out-of-bag evaluation: accuracy:0.936948 logloss:0.146417
# 	trees: 206, Out-of-bag evaluation: accuracy:0.936948 logloss:0.14433
# 	trees: 216, Out-of-bag evaluation: accuracy:0.936948 logloss:0.143354
# 	trees: 226, Out-of-bag evaluation: accuracy:0.936948 logloss:0.142925
# 	trees: 236, Out-of-bag evaluation: accuracy:0.936948 logloss:0.142623
# 	trees: 247, Out-of-bag evaluation: accuracy:0.936948 logloss:0.142252
# 	trees: 257, Out-of-bag evaluation: accuracy:0.936948 logloss:0.139403
# 	trees: 267, Out-of-bag evaluation: accuracy:0.936948 logloss:0.139367
# 	trees: 278, Out-of-bag evaluation: accuracy:0.936948 logloss:0.137409
# 	trees: 288, Out-of-bag evaluation: accuracy:0.936948 logloss:0.134756
# 	trees: 300, Out-of-bag evaluation: accuracy:0.936948 logloss:0.134769

# %%
# Model features
model.make_inspector().features()
# Out:
# ["DependenceEntropy" (1; #0),
#  "DependenceNonUniformity" (1; #1),
#  "DependenceNonUniformityNormalized" (1; #2),
#  "DependenceVariance" (1; #3),
#  "GrayLevelNonUniformity" (1; #4),
#  "GrayLevelVariance" (1; #5),
#  "HighGrayLevelEmphasis" (1; #6),
#  "LargeDependenceEmphasis" (1; #7),
#  "LargeDependenceHighGrayLevelEmphasis" (1; #8),
#  "LargeDependenceLowGrayLevelEmphasis" (1; #9),
#  "LowGrayLevelEmphasis" (1; #10),
#  "SmallDependenceEmphasis" (1; #11),
#  "SmallDependenceHighGrayLevelEmphasis" (1; #12),
#  "SmallDependenceLowGrayLevelEmphasis" (1; #13)]

# %%
# Feature importance
model.make_inspector().variable_importances()
# Out:
# {'INV_MEAN_MIN_DEPTH': [("HighGrayLevelEmphasis" (1; #6), 0.3750800021830053),
#   ("SmallDependenceHighGrayLevelEmphasis" (1; #12), 0.3566646757606724),
#   ("LowGrayLevelEmphasis" (1; #10), 0.32316724417850107),
#   ("DependenceEntropy" (1; #0), 0.31011644133999827),
#   ("LargeDependenceLowGrayLevelEmphasis" (1; #9), 0.28804652637225986),
#   ("GrayLevelNonUniformity" (1; #4), 0.2819018981394477),
#   ("SmallDependenceLowGrayLevelEmphasis" (1; #13), 0.2796923384277296),
#   ("LargeDependenceHighGrayLevelEmphasis" (1; #8), 0.27917838834304676),
#   ("GrayLevelVariance" (1; #5), 0.27434892029546953),
#   ("SmallDependenceEmphasis" (1; #11), 0.26660713851193035),
#   ("LargeDependenceEmphasis" (1; #7), 0.2623238422531538),
#   ("DependenceNonUniformity" (1; #1), 0.2613907231187649),
#   ("DependenceVariance" (1; #3), 0.261034400604937),
#   ("DependenceNonUniformityNormalized" (1; #2), 0.2600573570948705)],
#  'SUM_SCORE': [("HighGrayLevelEmphasis" (1; #6), 31447.865016914522),
#   ("SmallDependenceHighGrayLevelEmphasis" (1; #12), 25674.490975039615),
#   ("LowGrayLevelEmphasis" (1; #10), 14276.76611908977),
#   ("DependenceEntropy" (1; #0), 8376.396727373198),
#   ("LargeDependenceLowGrayLevelEmphasis" (1; #9), 7171.031143063963),
#   ("GrayLevelNonUniformity" (1; #4), 5812.964614483679),
#   ("LargeDependenceHighGrayLevelEmphasis" (1; #8), 2438.4139151299614),
#   ("SmallDependenceLowGrayLevelEmphasis" (1; #13), 2100.3242343573943),
#   ("GrayLevelVariance" (1; #5), 1353.2573360206277),
#   ("SmallDependenceEmphasis" (1; #11), 797.8908332069306),
#   ("LargeDependenceEmphasis" (1; #7), 797.866930248744),
#   ("DependenceNonUniformity" (1; #1), 352.07915714242256),
#   ("DependenceNonUniformityNormalized" (1; #2), 346.1750412482987),
#   ("DependenceVariance" (1; #3), 326.46209717356896)],
#  'NUM_AS_ROOT': [("HighGrayLevelEmphasis" (1; #6), 104.0),
#   ("SmallDependenceHighGrayLevelEmphasis" (1; #12), 84.0),
#   ("LowGrayLevelEmphasis" (1; #10), 52.0),
#   ("LargeDependenceLowGrayLevelEmphasis" (1; #9), 26.0),
#   ("DependenceEntropy" (1; #0), 16.0),
#   ("LargeDependenceHighGrayLevelEmphasis" (1; #8), 9.0),
#   ("SmallDependenceLowGrayLevelEmphasis" (1; #13), 5.0),
#   ("GrayLevelNonUniformity" (1; #4), 2.0),
#   ("GrayLevelVariance" (1; #5), 2.0)],
#  'NUM_NODES': [("HighGrayLevelEmphasis" (1; #6), 233.0),
#   ("DependenceEntropy" (1; #0), 207.0),
#   ("SmallDependenceHighGrayLevelEmphasis" (1; #12), 183.0),
#   ("GrayLevelNonUniformity" (1; #4), 182.0),
#   ("LowGrayLevelEmphasis" (1; #10), 168.0),
#   ("SmallDependenceLowGrayLevelEmphasis" (1; #13), 106.0),
#   ("LargeDependenceHighGrayLevelEmphasis" (1; #8), 96.0),
#   ("LargeDependenceLowGrayLevelEmphasis" (1; #9), 87.0),
#   ("GrayLevelVariance" (1; #5), 74.0),
#   ("SmallDependenceEmphasis" (1; #11), 66.0),
#   ("LargeDependenceEmphasis" (1; #7), 42.0),
#   ("DependenceVariance" (1; #3), 41.0),
#   ("DependenceNonUniformity" (1; #1), 34.0),
#   ("DependenceNonUniformityNormalized" (1; #2), 30.0)]}

# %%
# Model self evaluation
model.make_inspector().evaluation()
# Out:
# Evaluation(num_examples=507, accuracy=0.9369481412085428, loss=0.1347694939458861, rmse=None, ndcg=None, aucs=None, auuc=None, qini=None)

# %%
logs = model.make_inspector().training_logs()

plt.figure(figsize=(12, 4))
plt.subplot(1, 2, 1)
plt.plot([log.num_trees for log in logs], [log.evaluation.accuracy for log in logs])
plt.xlabel("Number of trees")
plt.ylabel("Accuracy (out-of-bag)")
plt.subplot(1, 2, 2)
plt.plot([log.num_trees for log in logs], [log.evaluation.loss for log in logs])
plt.xlabel("Number of trees")
plt.ylabel("Logloss (out-of-bag)")
plt.show()

# %% [markdown]
# Calculate the score of our hold-out validation dataset

# %%
predictions = model.predict(val_ds)
y_true      = validation_data["label"]

from sklearn.metrics import roc_auc_score
ROC_AUC = roc_auc_score(y_true, predictions)
print("The ROC AUC score is %.5f" % ROC_AUC )
# Out:
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 57ms/step
# The ROC AUC score is 1.00000

# %%
# Compute binary classification metrics with sklearn
import numpy as np
from sklearn.metrics import (
    accuracy_score,
    precision_score,
    recall_score,
    f1_score,
    roc_auc_score,
    average_precision_score,
    confusion_matrix,
    classification_report,
    matthews_corrcoef,
    log_loss,
    brier_score_loss,
)

# Get predictions (probabilities or class labels)
preds = model.predict(test_ds)
# If model outputs probabilities, convert to labels by threshold 0.5
if preds.ndim == 2:
    # For TFDF classification, preds may be class probabilities with shape (N, 2)
    if preds.shape[1] == 2:
        pos_probs = preds[:, 1]
    else:
        # If single-probability column (positive class)
        pos_probs = preds[:, -1]
    y_pred = (pos_probs >= 0.5).astype(int)
else:
    # Already class labels
    y_pred = preds.astype(int)
    pos_probs = None

# Ground truth labels (must be 0/1 integers)
y_true = test_data["label"].astype(int).to_numpy()

# Core metrics
metrics = {}
metrics["accuracy"] = accuracy_score(y_true, y_pred)
metrics["precision"] = precision_score(y_true, y_pred, zero_division=0)
metrics["recall"] = recall_score(y_true, y_pred, zero_division=0)
metrics["f1"] = f1_score(y_true, y_pred, zero_division=0)
metrics["mcc"] = matthews_corrcoef(y_true, y_pred)

# Probabilistic metrics (only if we have probabilities)
if pos_probs is not None:
    metrics["roc_auc"] = roc_auc_score(y_true, pos_probs)
    metrics["pr_auc"] = average_precision_score(y_true, pos_probs)
    metrics["log_loss"] = log_loss(y_true, pos_probs, labels=[0,1])
    metrics["brier_score"] = brier_score_loss(y_true, pos_probs)

# Confusion matrix and detailed report
cm = confusion_matrix(y_true, y_pred, labels=[0,1])
report = classification_report(y_true, y_pred, digits=4)

print("Sklearn binary metrics:")
for k, v in metrics.items():
    print(f"{k}: {v:.4f}")
print("\nConfusion matrix:\n", cm)
print("\nClassification report:\n", report)
# Out:
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 64ms/step
# Sklearn binary metrics:
# accuracy: 0.9932
# precision: 1.0000
# recall: 0.7500
# f1: 0.8571
# mcc: 0.8630
# roc_auc: 1.0000
# pr_auc: 1.0000
# log_loss: 0.0378
# brier_score: 0.0083
#
# Confusion matrix:
#  [[142   0]
#  [  1   3]]
#
# Classification report:
#                precision    recall  f1-score   support
#
#            0     0.9930    1.0000    0.9965       142
#            1     1.0000    0.7500    0.8571         4
#
#     accuracy                         0.9932       146
#    macro avg     0.9965    0.8750    0.9268       146
# weighted avg     0.9932    0.9932    0.9927       146
