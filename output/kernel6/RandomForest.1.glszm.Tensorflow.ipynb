# %%
# Import packages and modules
import numpy  as np
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow_decision_forests as tfdf

from sklearn.model_selection import train_test_split
# Out:
# 2026-08-15 05:22:18.743354: I tensorflow/core/util/port.cc:113] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2026-08-15 05:22:19.094024: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2026-08-15 05:22:23.864257: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
# Check the version of TensorFlow Decision Forests
print("Found TensorFlow Decision Forests v" + tfdf.__version__)
# Out:
# Found TensorFlow Decision Forests v1.9.1

# %%
datasetPath = 'dataset/firstorder/kernel5/dataset.csv'

# %%
# Parameters
datasetPath = "dataset/glszm/kernel6/1.dataset.csv"

# %%
# train/validation/test = 70/10/20
dataset = pd.read_csv(datasetPath)

train_data, temp_data = train_test_split(dataset, test_size=0.3, random_state=42)
validation_data, test_data = train_test_split(temp_data, test_size=2/3, random_state=42)

# %%
from sklearn.utils.class_weight import compute_class_weight

# tinh class weight tren tap train
classes = np.array([0, 1])
weights = compute_class_weight(class_weight="balanced", classes=classes, y=train_data["label"])
class_weight = {0: weights[0], 1: weights[1]}

# gan sample_weight cho tung dong
train_data["sample_weight"] = train_data["label"].map(class_weight)
validation_data["sample_weight"] = validation_data["label"].map(class_weight)
test_data["sample_weight"] = test_data["label"].map(class_weight)

# Convert the dataset into a TensorFlow dataset.
train_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    train_data, label="label", weight="sample_weight"
)         
val_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    validation_data, label="label", weight="sample_weight"
)
test_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    test_data, label="label", weight="sample_weight"
)
# Out:
# 2026-08-15 05:22:36.811721: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:984] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2026-08-15 05:22:36.813332: W tensorflow/core/common_runtime/gpu/gpu_device.cc:2251] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...

# %%
import keras

# %%
# %%time

# Train a Random Forest model.
model = tfdf.keras.RandomForestModel()

# Add evaluation metrics
model.compile(
    metrics=["accuracy"]
)
model.fit(x=train_ds)

# # Train a Gradient Boosted Trees model.
# model = tfdf.keras.GradientBoostedTreesModel(num_trees=1500)
# model.fit(train_ds)
# Out:
# Use /tmp/tmpbesud1zl as temporary training directory
# Reading training dataset...
# Training dataset read in 0:00:02.601537. Found 507 examples.
# Training model...
# Model trained in 0:00:00.041721
# Compiling model...
# [INFO 26-08-15 05:22:39.6225 UTC kernel.cc:1233] Loading model from path /tmp/tmpbesud1zl/model/ with prefix a60fd538e10e4722
# [INFO 26-08-15 05:22:39.6269 UTC decision_forest.cc:734] Model loaded with 300 root(s), 3292 node(s), and 16 input feature(s).
# [INFO 26-08-15 05:22:39.6269 UTC abstract_model.cc:1362] Engine "RandomForestOptPred" built
# [INFO 26-08-15 05:22:39.6270 UTC kernel.cc:1061] Use fast generic engine
# Model compiled.
# CPU times: user 5.43 s, sys: 89.9 ms, total: 5.52 s
# Wall time: 6.08 s

# %%
# Evaluate the model
evaluate = model.evaluate(val_ds, return_dict=True)
print()

for name, value in evaluate.items():
    print(f"{name}: {value:.4f}")
# Out:
# WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 1/1 [==============================] - ETA: 0s - loss: 0.0000e+00 - accuracy: 1.0000
# 1/1 [==============================] - 4s 4s/step - loss: 0.0000e+00 - accuracy: 1.0000
# loss: 0.0000
# accuracy: 1.0000

# %%
# Model Summary
model.summary()
# Out:
# Model: "random_forest_model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
# =================================================================
# Total params: 1 (1.00 Byte)
# Trainable params: 0 (0.00 Byte)
# Non-trainable params: 1 (1.00 Byte)
# _________________________________________________________________
# Type: "RANDOM_FOREST"
# Task: CLASSIFICATION
# Label: "__LABEL"
#
# Input Features (16):
# 	GrayLevelNonUniformity
# 	GrayLevelNonUniformityNormalized
# 	GrayLevelVariance
# 	HighGrayLevelZoneEmphasis
# 	LargeAreaEmphasis
# 	LargeAreaHighGrayLevelEmphasis
# 	LargeAreaLowGrayLevelEmphasis
# 	LowGrayLevelZoneEmphasis
# 	SizeZoneNonUniformity
# 	SizeZoneNonUniformityNormalized
# 	SmallAreaEmphasis
# 	SmallAreaHighGrayLevelEmphasis
# 	SmallAreaLowGrayLevelEmphasis
# 	ZoneEntropy
# 	ZonePercentage
# 	ZoneVariance
#
# Trained with weights
#
# Variable Importance: INV_MEAN_MIN_DEPTH:
#     1.   "SmallAreaHighGrayLevelEmphasis"  0.360542 ################
#     2.        "HighGrayLevelZoneEmphasis"  0.338375 ############
#     3.         "LowGrayLevelZoneEmphasis"  0.322395 #########
#     4.    "SmallAreaLowGrayLevelEmphasis"  0.308777 #######
#     5.    "LargeAreaLowGrayLevelEmphasis"  0.306336 #######
#     6. "GrayLevelNonUniformityNormalized"  0.299652 #####
#     7.                      "ZoneEntropy"  0.275896 #
#     8.                "GrayLevelVariance"  0.275885 #
#     9.           "GrayLevelNonUniformity"  0.272195 #
#    10.            "SizeZoneNonUniformity"  0.268686
#    11.                     "ZoneVariance"  0.268477
#    12.                "SmallAreaEmphasis"  0.267428
#    13.                "LargeAreaEmphasis"  0.266546
#    14.  "SizeZoneNonUniformityNormalized"  0.266131
#    15.                   "ZonePercentage"  0.265461
#    16.   "LargeAreaHighGrayLevelEmphasis"  0.263924
#
# Variable Importance: NUM_AS_ROOT:
#     1.   "SmallAreaHighGrayLevelEmphasis" 95.000000 ################
#     2.        "HighGrayLevelZoneEmphasis" 60.000000 ##########
#     3.         "LowGrayLevelZoneEmphasis" 47.000000 #######
#     4.    "SmallAreaLowGrayLevelEmphasis" 30.000000 ####
#     5.    "LargeAreaLowGrayLevelEmphasis" 29.000000 ####
#     6. "GrayLevelNonUniformityNormalized" 21.000000 ###
#     7.                "GrayLevelVariance"  6.000000
#     8.                      "ZoneEntropy"  6.000000
#     9.            "SizeZoneNonUniformity"  4.000000
#    10.           "GrayLevelNonUniformity"  1.000000
#    11.                   "ZonePercentage"  1.000000
#
# Variable Importance: NUM_NODES:
#     1.        "HighGrayLevelZoneEmphasis" 183.000000 ################
#     2.   "SmallAreaHighGrayLevelEmphasis" 182.000000 ###############
#     3. "GrayLevelNonUniformityNormalized" 154.000000 ############
#     4.         "LowGrayLevelZoneEmphasis" 151.000000 ############
#     5.    "SmallAreaLowGrayLevelEmphasis" 151.000000 ############
#     6.    "LargeAreaLowGrayLevelEmphasis" 116.000000 ########
#     7.                      "ZoneEntropy" 93.000000 ######
#     8.                "GrayLevelVariance" 85.000000 #####
#     9.           "GrayLevelNonUniformity" 59.000000 ##
#    10.                     "ZoneVariance" 58.000000 ##
#    11.                "SmallAreaEmphasis" 49.000000 #
#    12.                "LargeAreaEmphasis" 48.000000 #
#    13.            "SizeZoneNonUniformity" 47.000000 #
#    14.  "SizeZoneNonUniformityNormalized" 46.000000 #
#    15.                   "ZonePercentage" 40.000000
#    16.   "LargeAreaHighGrayLevelEmphasis" 34.000000
#
# Variable Importance: SUM_SCORE:
#     1.   "SmallAreaHighGrayLevelEmphasis" 30903.689634 ################
#     2.        "HighGrayLevelZoneEmphasis" 21601.484967 ###########
#     3.         "LowGrayLevelZoneEmphasis" 12908.023549 ######
#     4. "GrayLevelNonUniformityNormalized" 8459.676483 ####
#     5.    "SmallAreaLowGrayLevelEmphasis" 7316.227299 ###
#     6.    "LargeAreaLowGrayLevelEmphasis" 7245.598753 ###
#     7.                      "ZoneEntropy" 3267.313796 #
#     8.                "GrayLevelVariance" 3265.900032 #
#     9.                     "ZoneVariance" 1197.777576
#    10.                "LargeAreaEmphasis" 1176.068582
#    11.           "GrayLevelNonUniformity" 1019.649484
#    12.            "SizeZoneNonUniformity" 1002.108772
#    13.                   "ZonePercentage" 732.402404
#    14.   "LargeAreaHighGrayLevelEmphasis" 457.082430
#    15.                "SmallAreaEmphasis" 355.500726
#    16.  "SizeZoneNonUniformityNormalized" 228.692439
#
#
#
# Winner takes all: true
# Out-of-bag evaluation: accuracy:0.963487 logloss:0.188427
# Number of trees: 300
# Total number of nodes: 3292
#
# Number of nodes by tree:
# Count: 300 Average: 10.9733 StdDev: 2.41646
# Min: 5 Max: 17 Ignored: 0
# ----------------------------------------------
# [  5,  6)   5   1.67%   1.67%
# [  6,  7)   0   0.00%   1.67%
# [  7,  8)  21   7.00%   8.67% ##
# [  8,  9)   0   0.00%   8.67%
# [  9, 10)  76  25.33%  34.00% #######
# [ 10, 11)   0   0.00%  34.00%
# [ 11, 12) 111  37.00%  71.00% ##########
# [ 12, 13)   0   0.00%  71.00%
# [ 13, 14)  55  18.33%  89.33% #####
# [ 14, 15)   0   0.00%  89.33%
# [ 15, 16)  22   7.33%  96.67% ##
# [ 16, 17)   0   0.00%  96.67%
# [ 17, 17]  10   3.33% 100.00% #
#
# Depth by leafs:
# Count: 1796 Average: 2.92762 StdDev: 1.05437
# Min: 1 Max: 6 Ignored: 0
# ----------------------------------------------
# [ 1, 2)  95   5.29%   5.29% ##
# [ 2, 3) 619  34.47%  39.76% ##########
# [ 3, 4) 555  30.90%  70.66% #########
# [ 4, 5) 387  21.55%  92.20% ######
# [ 5, 6) 128   7.13%  99.33% ##
# [ 6, 6]  12   0.67% 100.00%
#
# Number of training obs by leaf:
# Count: 1796 Average: 84.6882 StdDev: 157.188
# Min: 5 Max: 481 Ignored: 0
# ----------------------------------------------
# [   5,  28) 1355  75.45%  75.45% ##########
# [  28,  52)   60   3.34%  78.79%
# [  52,  76)   19   1.06%  79.84%
# [  76, 100)   23   1.28%  81.12%
# [ 100, 124)   13   0.72%  81.85%
# [ 124, 148)    5   0.28%  82.13%
# [ 148, 171)    6   0.33%  82.46%
# [ 171, 195)    8   0.45%  82.91%
# [ 195, 219)    8   0.45%  83.35%
# [ 219, 243)    5   0.28%  83.63%
# [ 243, 267)   11   0.61%  84.24%
# [ 267, 291)    5   0.28%  84.52%
# [ 291, 315)    4   0.22%  84.74%
# [ 315, 338)    3   0.17%  84.91%
# [ 338, 362)   15   0.84%  85.75%
# [ 362, 386)   16   0.89%  86.64%
# [ 386, 410)   14   0.78%  87.42%
# [ 410, 434)   10   0.56%  87.97%
# [ 434, 458)   79   4.40%  92.37% #
# [ 458, 481]  137   7.63% 100.00% #
#
# Attribute in nodes:
# 	183 : HighGrayLevelZoneEmphasis [NUMERICAL]
# 	182 : SmallAreaHighGrayLevelEmphasis [NUMERICAL]
# 	154 : GrayLevelNonUniformityNormalized [NUMERICAL]
# 	151 : SmallAreaLowGrayLevelEmphasis [NUMERICAL]
# 	151 : LowGrayLevelZoneEmphasis [NUMERICAL]
# 	116 : LargeAreaLowGrayLevelEmphasis [NUMERICAL]
# 	93 : ZoneEntropy [NUMERICAL]
# 	85 : GrayLevelVariance [NUMERICAL]
# 	59 : GrayLevelNonUniformity [NUMERICAL]
# 	58 : ZoneVariance [NUMERICAL]
# 	49 : SmallAreaEmphasis [NUMERICAL]
# 	48 : LargeAreaEmphasis [NUMERICAL]
# 	47 : SizeZoneNonUniformity [NUMERICAL]
# 	46 : SizeZoneNonUniformityNormalized [NUMERICAL]
# 	40 : ZonePercentage [NUMERICAL]
# 	34 : LargeAreaHighGrayLevelEmphasis [NUMERICAL]
#
# Attribute in nodes with depth <= 0:
# 	95 : SmallAreaHighGrayLevelEmphasis [NUMERICAL]
# 	60 : HighGrayLevelZoneEmphasis [NUMERICAL]
# 	47 : LowGrayLevelZoneEmphasis [NUMERICAL]
# 	30 : SmallAreaLowGrayLevelEmphasis [NUMERICAL]
# 	29 : LargeAreaLowGrayLevelEmphasis [NUMERICAL]
# 	21 : GrayLevelNonUniformityNormalized [NUMERICAL]
# 	6 : ZoneEntropy [NUMERICAL]
# 	6 : GrayLevelVariance [NUMERICAL]
# 	4 : SizeZoneNonUniformity [NUMERICAL]
# 	1 : ZonePercentage [NUMERICAL]
# 	1 : GrayLevelNonUniformity [NUMERICAL]
#
# Attribute in nodes with depth <= 1:
# 	134 : SmallAreaHighGrayLevelEmphasis [NUMERICAL]
# 	117 : HighGrayLevelZoneEmphasis [NUMERICAL]
# 	106 : GrayLevelNonUniformityNormalized [NUMERICAL]
# 	99 : LowGrayLevelZoneEmphasis [NUMERICAL]
# 	69 : SmallAreaLowGrayLevelEmphasis [NUMERICAL]
# 	67 : LargeAreaLowGrayLevelEmphasis [NUMERICAL]
# 	48 : GrayLevelVariance [NUMERICAL]
# 	44 : ZoneEntropy [NUMERICAL]
# 	26 : ZoneVariance [NUMERICAL]
# 	25 : LargeAreaEmphasis [NUMERICAL]
# 	19 : GrayLevelNonUniformity [NUMERICAL]
# 	16 : SizeZoneNonUniformity [NUMERICAL]
# 	11 : ZonePercentage [NUMERICAL]
# 	9 : SmallAreaEmphasis [NUMERICAL]
# 	8 : SizeZoneNonUniformityNormalized [NUMERICAL]
# 	7 : LargeAreaHighGrayLevelEmphasis [NUMERICAL]
#
# Attribute in nodes with depth <= 2:
# 	160 : SmallAreaHighGrayLevelEmphasis [NUMERICAL]
# 	157 : HighGrayLevelZoneEmphasis [NUMERICAL]
# 	135 : GrayLevelNonUniformityNormalized [NUMERICAL]
# 	132 : LowGrayLevelZoneEmphasis [NUMERICAL]
# 	127 : SmallAreaLowGrayLevelEmphasis [NUMERICAL]
# 	90 : LargeAreaLowGrayLevelEmphasis [NUMERICAL]
# 	70 : GrayLevelVariance [NUMERICAL]
# 	68 : ZoneEntropy [NUMERICAL]
# 	51 : ZoneVariance [NUMERICAL]
# 	38 : LargeAreaEmphasis [NUMERICAL]
# 	33 : GrayLevelNonUniformity [NUMERICAL]
# 	30 : SizeZoneNonUniformity [NUMERICAL]
# 	29 : SmallAreaEmphasis [NUMERICAL]
# 	29 : SizeZoneNonUniformityNormalized [NUMERICAL]
# 	26 : ZonePercentage [NUMERICAL]
# 	21 : LargeAreaHighGrayLevelEmphasis [NUMERICAL]
#
# Attribute in nodes with depth <= 3:
# 	179 : SmallAreaHighGrayLevelEmphasis [NUMERICAL]
# 	176 : HighGrayLevelZoneEmphasis [NUMERICAL]
# 	148 : LowGrayLevelZoneEmphasis [NUMERICAL]
# 	148 : GrayLevelNonUniformityNormalized [NUMERICAL]
# 	145 : SmallAreaLowGrayLevelEmphasis [NUMERICAL]
# 	111 : LargeAreaLowGrayLevelEmphasis [NUMERICAL]
# 	86 : ZoneEntropy [NUMERICAL]
# 	82 : GrayLevelVariance [NUMERICAL]
# 	55 : ZoneVariance [NUMERICAL]
# 	54 : GrayLevelNonUniformity [NUMERICAL]
# 	45 : SmallAreaEmphasis [NUMERICAL]
# 	45 : LargeAreaEmphasis [NUMERICAL]
# 	43 : SizeZoneNonUniformity [NUMERICAL]
# 	42 : SizeZoneNonUniformityNormalized [NUMERICAL]
# 	36 : ZonePercentage [NUMERICAL]
# 	28 : LargeAreaHighGrayLevelEmphasis [NUMERICAL]
#
# Attribute in nodes with depth <= 5:
# 	183 : HighGrayLevelZoneEmphasis [NUMERICAL]
# 	182 : SmallAreaHighGrayLevelEmphasis [NUMERICAL]
# 	154 : GrayLevelNonUniformityNormalized [NUMERICAL]
# 	151 : SmallAreaLowGrayLevelEmphasis [NUMERICAL]
# 	151 : LowGrayLevelZoneEmphasis [NUMERICAL]
# 	116 : LargeAreaLowGrayLevelEmphasis [NUMERICAL]
# 	93 : ZoneEntropy [NUMERICAL]
# 	85 : GrayLevelVariance [NUMERICAL]
# 	59 : GrayLevelNonUniformity [NUMERICAL]
# 	58 : ZoneVariance [NUMERICAL]
# 	49 : SmallAreaEmphasis [NUMERICAL]
# 	48 : LargeAreaEmphasis [NUMERICAL]
# 	47 : SizeZoneNonUniformity [NUMERICAL]
# 	46 : SizeZoneNonUniformityNormalized [NUMERICAL]
# 	40 : ZonePercentage [NUMERICAL]
# 	34 : LargeAreaHighGrayLevelEmphasis [NUMERICAL]
#
# Condition type in nodes:
# 	1496 : HigherCondition
# Condition type in nodes with depth <= 0:
# 	300 : HigherCondition
# Condition type in nodes with depth <= 1:
# 	805 : HigherCondition
# Condition type in nodes with depth <= 2:
# 	1196 : HigherCondition
# Condition type in nodes with depth <= 3:
# 	1423 : HigherCondition
# Condition type in nodes with depth <= 5:
# 	1496 : HigherCondition
# Node format: NOT_SET
#
# Training OOB:
# 	trees: 1, Out-of-bag evaluation: accuracy:0.905405 logloss:3.40953
# 	trees: 12, Out-of-bag evaluation: accuracy:0.86337 logloss:4.18892
# 	trees: 22, Out-of-bag evaluation: accuracy:0.931112 logloss:1.34593
# 	trees: 32, Out-of-bag evaluation: accuracy:0.947862 logloss:1.24054
# 	trees: 42, Out-of-bag evaluation: accuracy:0.963487 logloss:1.224
# 	trees: 52, Out-of-bag evaluation: accuracy:0.963487 logloss:1.21884
# 	trees: 63, Out-of-bag evaluation: accuracy:0.963487 logloss:1.2229
# 	trees: 73, Out-of-bag evaluation: accuracy:0.962434 logloss:1.22821
# 	trees: 83, Out-of-bag evaluation: accuracy:0.962434 logloss:0.715535
# 	trees: 93, Out-of-bag evaluation: accuracy:0.962434 logloss:0.714218
# 	trees: 103, Out-of-bag evaluation: accuracy:0.963487 logloss:0.715584
# 	trees: 113, Out-of-bag evaluation: accuracy:0.962434 logloss:0.713808
# 	trees: 123, Out-of-bag evaluation: accuracy:0.962434 logloss:0.712987
# 	trees: 133, Out-of-bag evaluation: accuracy:0.962434 logloss:0.713045
# 	trees: 144, Out-of-bag evaluation: accuracy:0.962434 logloss:0.713711
# 	trees: 155, Out-of-bag evaluation: accuracy:0.963487 logloss:0.2021
# 	trees: 165, Out-of-bag evaluation: accuracy:0.963487 logloss:0.19925
# 	trees: 175, Out-of-bag evaluation: accuracy:0.963487 logloss:0.202419
# 	trees: 185, Out-of-bag evaluation: accuracy:0.963487 logloss:0.194742
# 	trees: 196, Out-of-bag evaluation: accuracy:0.963487 logloss:0.195665
# 	trees: 207, Out-of-bag evaluation: accuracy:0.963487 logloss:0.200005
# 	trees: 217, Out-of-bag evaluation: accuracy:0.963487 logloss:0.199671
# 	trees: 228, Out-of-bag evaluation: accuracy:0.962434 logloss:0.202616
# 	trees: 238, Out-of-bag evaluation: accuracy:0.962434 logloss:0.19308
# 	trees: 248, Out-of-bag evaluation: accuracy:0.962434 logloss:0.195024
# 	trees: 258, Out-of-bag evaluation: accuracy:0.962434 logloss:0.19655
# 	trees: 268, Out-of-bag evaluation: accuracy:0.962434 logloss:0.193389
# 	trees: 278, Out-of-bag evaluation: accuracy:0.963487 logloss:0.188654
# 	trees: 289, Out-of-bag evaluation: accuracy:0.963487 logloss:0.186497
# 	trees: 299, Out-of-bag evaluation: accuracy:0.963487 logloss:0.188524
# 	trees: 300, Out-of-bag evaluation: accuracy:0.963487 logloss:0.188427

# %%
# Model features
model.make_inspector().features()
# Out:
# ["GrayLevelNonUniformity" (1; #0),
#  "GrayLevelNonUniformityNormalized" (1; #1),
#  "GrayLevelVariance" (1; #2),
#  "HighGrayLevelZoneEmphasis" (1; #3),
#  "LargeAreaEmphasis" (1; #4),
#  "LargeAreaHighGrayLevelEmphasis" (1; #5),
#  "LargeAreaLowGrayLevelEmphasis" (1; #6),
#  "LowGrayLevelZoneEmphasis" (1; #7),
#  "SizeZoneNonUniformity" (1; #8),
#  "SizeZoneNonUniformityNormalized" (1; #9),
#  "SmallAreaEmphasis" (1; #10),
#  "SmallAreaHighGrayLevelEmphasis" (1; #11),
#  "SmallAreaLowGrayLevelEmphasis" (1; #12),
#  "ZoneEntropy" (1; #13),
#  "ZonePercentage" (1; #14),
#  "ZoneVariance" (1; #15)]

# %%
# Feature importance
model.make_inspector().variable_importances()
# Out:
# {'INV_MEAN_MIN_DEPTH': [("SmallAreaHighGrayLevelEmphasis" (1; #11),
#    0.3605420148289596),
#   ("HighGrayLevelZoneEmphasis" (1; #3), 0.3383746380152269),
#   ("LowGrayLevelZoneEmphasis" (1; #7), 0.32239452134008656),
#   ("SmallAreaLowGrayLevelEmphasis" (1; #12), 0.30877736416859236),
#   ("LargeAreaLowGrayLevelEmphasis" (1; #6), 0.30633555413103225),
#   ("GrayLevelNonUniformityNormalized" (1; #1), 0.29965183310819826),
#   ("ZoneEntropy" (1; #13), 0.2758962980263928),
#   ("GrayLevelVariance" (1; #2), 0.27588482027709654),
#   ("GrayLevelNonUniformity" (1; #0), 0.2721954507355039),
#   ("SizeZoneNonUniformity" (1; #8), 0.2686855518964723),
#   ("ZoneVariance" (1; #15), 0.2684765871369885),
#   ("SmallAreaEmphasis" (1; #10), 0.267428294904076),
#   ("LargeAreaEmphasis" (1; #4), 0.2665461332829388),
#   ("SizeZoneNonUniformityNormalized" (1; #9), 0.26613149359964333),
#   ("ZonePercentage" (1; #14), 0.2654610894087698),
#   ("LargeAreaHighGrayLevelEmphasis" (1; #5), 0.2639235375808267)],
#  'SUM_SCORE': [("SmallAreaHighGrayLevelEmphasis" (1; #11), 30903.689633677113),
#   ("HighGrayLevelZoneEmphasis" (1; #3), 21601.48496744402),
#   ("LowGrayLevelZoneEmphasis" (1; #7), 12908.023548549805),
#   ("GrayLevelNonUniformityNormalized" (1; #1), 8459.67648297355),
#   ("SmallAreaLowGrayLevelEmphasis" (1; #12), 7316.227298690291),
#   ("LargeAreaLowGrayLevelEmphasis" (1; #6), 7245.59875267134),
#   ("ZoneEntropy" (1; #13), 3267.313796482389),
#   ("GrayLevelVariance" (1; #2), 3265.9000319913034),
#   ("ZoneVariance" (1; #15), 1197.7775761137968),
#   ("LargeAreaEmphasis" (1; #4), 1176.0685817631907),
#   ("GrayLevelNonUniformity" (1; #0), 1019.6494841163367),
#   ("SizeZoneNonUniformity" (1; #8), 1002.1087722260131),
#   ("ZonePercentage" (1; #14), 732.4024043095695),
#   ("LargeAreaHighGrayLevelEmphasis" (1; #5), 457.0824298357225),
#   ("SmallAreaEmphasis" (1; #10), 355.5007260377381),
#   ("SizeZoneNonUniformityNormalized" (1; #9), 228.69243927324146)],
#  'NUM_AS_ROOT': [("SmallAreaHighGrayLevelEmphasis" (1; #11), 95.0),
#   ("HighGrayLevelZoneEmphasis" (1; #3), 60.0),
#   ("LowGrayLevelZoneEmphasis" (1; #7), 47.0),
#   ("SmallAreaLowGrayLevelEmphasis" (1; #12), 30.0),
#   ("LargeAreaLowGrayLevelEmphasis" (1; #6), 29.0),
#   ("GrayLevelNonUniformityNormalized" (1; #1), 21.0),
#   ("GrayLevelVariance" (1; #2), 6.0),
#   ("ZoneEntropy" (1; #13), 6.0),
#   ("SizeZoneNonUniformity" (1; #8), 4.0),
#   ("GrayLevelNonUniformity" (1; #0), 1.0),
#   ("ZonePercentage" (1; #14), 1.0)],
#  'NUM_NODES': [("HighGrayLevelZoneEmphasis" (1; #3), 183.0),
#   ("SmallAreaHighGrayLevelEmphasis" (1; #11), 182.0),
#   ("GrayLevelNonUniformityNormalized" (1; #1), 154.0),
#   ("LowGrayLevelZoneEmphasis" (1; #7), 151.0),
#   ("SmallAreaLowGrayLevelEmphasis" (1; #12), 151.0),
#   ("LargeAreaLowGrayLevelEmphasis" (1; #6), 116.0),
#   ("ZoneEntropy" (1; #13), 93.0),
#   ("GrayLevelVariance" (1; #2), 85.0),
#   ("GrayLevelNonUniformity" (1; #0), 59.0),
#   ("ZoneVariance" (1; #15), 58.0),
#   ("SmallAreaEmphasis" (1; #10), 49.0),
#   ("LargeAreaEmphasis" (1; #4), 48.0),
#   ("SizeZoneNonUniformity" (1; #8), 47.0),
#   ("SizeZoneNonUniformityNormalized" (1; #9), 46.0),
#   ("ZonePercentage" (1; #14), 40.0),
#   ("LargeAreaHighGrayLevelEmphasis" (1; #5), 34.0)]}

# %%
# Model self evaluation
model.make_inspector().evaluation()
# Out:
# Evaluation(num_examples=507, accuracy=0.9634868417050448, loss=0.18842718244935894, rmse=None, ndcg=None, aucs=None, auuc=None, qini=None)

# %%
logs = model.make_inspector().training_logs()

plt.figure(figsize=(12, 4))
plt.subplot(1, 2, 1)
plt.plot([log.num_trees for log in logs], [log.evaluation.accuracy for log in logs])
plt.xlabel("Number of trees")
plt.ylabel("Accuracy (out-of-bag)")
plt.subplot(1, 2, 2)
plt.plot([log.num_trees for log in logs], [log.evaluation.loss for log in logs])
plt.xlabel("Number of trees")
plt.ylabel("Logloss (out-of-bag)")
plt.show()

# %% [markdown]
# Calculate the score of our hold-out validation dataset

# %%
predictions = model.predict(val_ds)
y_true      = validation_data["label"]

from sklearn.metrics import roc_auc_score
ROC_AUC = roc_auc_score(y_true, predictions)
print("The ROC AUC score is %.5f" % ROC_AUC )
# Out:
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 68ms/step
# The ROC AUC score is 1.00000

# %%
# Compute binary classification metrics with sklearn
import numpy as np
from sklearn.metrics import (
    accuracy_score,
    precision_score,
    recall_score,
    f1_score,
    roc_auc_score,
    average_precision_score,
    confusion_matrix,
    classification_report,
    matthews_corrcoef,
    log_loss,
    brier_score_loss,
)

# Get predictions (probabilities or class labels)
preds = model.predict(test_ds)
# If model outputs probabilities, convert to labels by threshold 0.5
if preds.ndim == 2:
    # For TFDF classification, preds may be class probabilities with shape (N, 2)
    if preds.shape[1] == 2:
        pos_probs = preds[:, 1]
    else:
        # If single-probability column (positive class)
        pos_probs = preds[:, -1]
    y_pred = (pos_probs >= 0.5).astype(int)
else:
    # Already class labels
    y_pred = preds.astype(int)
    pos_probs = None

# Ground truth labels (must be 0/1 integers)
y_true = test_data["label"].astype(int).to_numpy()

# Core metrics
metrics = {}
metrics["accuracy"] = accuracy_score(y_true, y_pred)
metrics["precision"] = precision_score(y_true, y_pred, zero_division=0)
metrics["recall"] = recall_score(y_true, y_pred, zero_division=0)
metrics["f1"] = f1_score(y_true, y_pred, zero_division=0)
metrics["mcc"] = matthews_corrcoef(y_true, y_pred)

# Probabilistic metrics (only if we have probabilities)
if pos_probs is not None:
    metrics["roc_auc"] = roc_auc_score(y_true, pos_probs)
    metrics["pr_auc"] = average_precision_score(y_true, pos_probs)
    metrics["log_loss"] = log_loss(y_true, pos_probs, labels=[0,1])
    metrics["brier_score"] = brier_score_loss(y_true, pos_probs)

# Confusion matrix and detailed report
cm = confusion_matrix(y_true, y_pred, labels=[0,1])
report = classification_report(y_true, y_pred, digits=4)

print("Sklearn binary metrics:")
for k, v in metrics.items():
    print(f"{k}: {v:.4f}")
print("\nConfusion matrix:\n", cm)
print("\nClassification report:\n", report)
# Out:
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 67ms/step
# Sklearn binary metrics:
# accuracy: 0.9932
# precision: 1.0000
# recall: 0.7500
# f1: 0.8571
# mcc: 0.8630
# roc_auc: 0.9868
# pr_auc: 0.8333
# log_loss: 0.0374
# brier_score: 0.0098
#
# Confusion matrix:
#  [[142   0]
#  [  1   3]]
#
# Classification report:
#                precision    recall  f1-score   support
#
#            0     0.9930    1.0000    0.9965       142
#            1     1.0000    0.7500    0.8571         4
#
#     accuracy                         0.9932       146
#    macro avg     0.9965    0.8750    0.9268       146
# weighted avg     0.9932    0.9932    0.9927       146
