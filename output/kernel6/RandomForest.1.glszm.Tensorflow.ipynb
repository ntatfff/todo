# %%
# Import packages and modules
import numpy  as np
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow_decision_forests as tfdf

from sklearn.model_selection import train_test_split
# Out:
# 2026-08-12 05:59:15.374481: I tensorflow/core/util/port.cc:113] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2026-08-12 05:59:15.712372: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2026-08-12 05:59:20.215971: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
# Check the version of TensorFlow Decision Forests
print("Found TensorFlow Decision Forests v" + tfdf.__version__)
# Out:
# Found TensorFlow Decision Forests v1.9.1

# %%
datasetPath = 'dataset/firstorder/kernel5-radius5/dataset.csv'

# %%
# Parameters
datasetPath = "dataset/glszm/kernel6-radius6/1.dataset.csv"

# %%
# train/validation/test = 70/10/20
dataset = pd.read_csv(datasetPath)

train_data, temp_data = train_test_split(dataset, test_size=0.3, random_state=42)
validation_data, test_data = train_test_split(temp_data, test_size=2/3, random_state=42)

# %%
from sklearn.utils.class_weight import compute_class_weight

# tinh class weight tren tap train
classes = np.array([0, 1])
weights = compute_class_weight(class_weight="balanced", classes=classes, y=train_data["label"])
class_weight = {0: weights[0], 1: weights[1]}

# gan sample_weight cho tung dong
train_data["sample_weight"] = train_data["label"].map(class_weight)
validation_data["sample_weight"] = validation_data["label"].map(class_weight)
test_data["sample_weight"] = test_data["label"].map(class_weight)

# Convert the dataset into a TensorFlow dataset.
train_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    train_data, label="label", weight="sample_weight"
)         
val_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    validation_data, label="label", weight="sample_weight"
)
test_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    test_data, label="label", weight="sample_weight"
)
# Out:
# 2026-08-12 05:59:35.329959: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:984] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2026-08-12 05:59:35.331655: W tensorflow/core/common_runtime/gpu/gpu_device.cc:2251] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...

# %%
import keras

# %%
# %%time

# Train a Random Forest model.
model = tfdf.keras.RandomForestModel()

# Add evaluation metrics
model.compile(
    metrics=["accuracy"]
)
model.fit(x=train_ds)

# # Train a Gradient Boosted Trees model.
# model = tfdf.keras.GradientBoostedTreesModel(num_trees=1500)
# model.fit(train_ds)
# Out:
# Use /tmp/tmpaktv2xyg as temporary training directory
# Reading training dataset...
# Training dataset read in 0:00:02.484018. Found 450 examples.
# Training model...
# Model trained in 0:00:00.050859
# Compiling model...
# [INFO 26-08-12 05:59:38.0198 UTC kernel.cc:1233] Loading model from path /tmp/tmpaktv2xyg/model/ with prefix 69436d24af9142fe
# [INFO 26-08-12 05:59:38.0286 UTC decision_forest.cc:734] Model loaded with 300 root(s), 7436 node(s), and 16 input feature(s).
# [INFO 26-08-12 05:59:38.0286 UTC abstract_model.cc:1362] Engine "RandomForestOptPred" built
# [INFO 26-08-12 05:59:38.0286 UTC kernel.cc:1061] Use fast generic engine
# Model compiled.
# CPU times: user 5.62 s, sys: 48.6 ms, total: 5.67 s
# Wall time: 5.56 s

# %%
# Evaluate the model
evaluate = model.evaluate(val_ds, return_dict=True)
print()

for name, value in evaluate.items():
    print(f"{name}: {value:.4f}")
# Out:
# WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 1/1 [==============================] - ETA: 0s - loss: 0.0000e+00 - accuracy: 1.0000
# 1/1 [==============================] - 3s 3s/step - loss: 0.0000e+00 - accuracy: 1.0000
# loss: 0.0000
# accuracy: 1.0000

# %%
# Model Summary
model.summary()
# Out:
# Model: "random_forest_model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
# =================================================================
# Total params: 1 (1.00 Byte)
# Trainable params: 0 (0.00 Byte)
# Non-trainable params: 1 (1.00 Byte)
# _________________________________________________________________
# Type: "RANDOM_FOREST"
# Task: CLASSIFICATION
# Label: "__LABEL"
#
# Input Features (16):
# 	GrayLevelNonUniformity
# 	GrayLevelNonUniformityNormalized
# 	GrayLevelVariance
# 	HighGrayLevelZoneEmphasis
# 	LargeAreaEmphasis
# 	LargeAreaHighGrayLevelEmphasis
# 	LargeAreaLowGrayLevelEmphasis
# 	LowGrayLevelZoneEmphasis
# 	SizeZoneNonUniformity
# 	SizeZoneNonUniformityNormalized
# 	SmallAreaEmphasis
# 	SmallAreaHighGrayLevelEmphasis
# 	SmallAreaLowGrayLevelEmphasis
# 	ZoneEntropy
# 	ZonePercentage
# 	ZoneVariance
#
# Trained with weights
#
# Variable Importance: INV_MEAN_MIN_DEPTH:
#     1.        "HighGrayLevelZoneEmphasis"  0.309799 ################
#     2.   "SmallAreaHighGrayLevelEmphasis"  0.250699 #######
#     3.         "LowGrayLevelZoneEmphasis"  0.250268 #######
#     4.    "SmallAreaLowGrayLevelEmphasis"  0.234239 #####
#     5.   "LargeAreaHighGrayLevelEmphasis"  0.232274 ####
#     6.           "GrayLevelNonUniformity"  0.232117 ####
#     7.                      "ZoneEntropy"  0.223861 ###
#     8.    "LargeAreaLowGrayLevelEmphasis"  0.212367 ##
#     9. "GrayLevelNonUniformityNormalized"  0.209969 #
#    10.                "GrayLevelVariance"  0.209876 #
#    11.                "LargeAreaEmphasis"  0.203084
#    12.                     "ZoneVariance"  0.202693
#    13.                   "ZonePercentage"  0.200854
#    14.            "SizeZoneNonUniformity"  0.200100
#    15.  "SizeZoneNonUniformityNormalized"  0.199275
#    16.                "SmallAreaEmphasis"  0.197657
#
# Variable Importance: NUM_AS_ROOT:
#     1.        "HighGrayLevelZoneEmphasis" 106.000000 ################
#     2.         "LowGrayLevelZoneEmphasis" 60.000000 ########
#     3.    "SmallAreaLowGrayLevelEmphasis" 43.000000 ######
#     4.   "SmallAreaHighGrayLevelEmphasis" 40.000000 #####
#     5.   "LargeAreaHighGrayLevelEmphasis" 16.000000 ##
#     6.                      "ZoneEntropy" 13.000000 #
#     7.    "LargeAreaLowGrayLevelEmphasis" 10.000000 #
#     8.           "GrayLevelNonUniformity"  7.000000
#     9.  "SizeZoneNonUniformityNormalized"  3.000000
#    10. "GrayLevelNonUniformityNormalized"  2.000000
#
# Variable Importance: NUM_NODES:
#     1.        "HighGrayLevelZoneEmphasis" 384.000000 ################
#     2.           "GrayLevelNonUniformity" 315.000000 ###########
#     3.   "LargeAreaHighGrayLevelEmphasis" 300.000000 ###########
#     4.   "SmallAreaHighGrayLevelEmphasis" 289.000000 ##########
#     5.         "LowGrayLevelZoneEmphasis" 274.000000 #########
#     6.    "SmallAreaLowGrayLevelEmphasis" 241.000000 #######
#     7.                      "ZoneEntropy" 235.000000 #######
#     8.    "LargeAreaLowGrayLevelEmphasis" 229.000000 ######
#     9. "GrayLevelNonUniformityNormalized" 214.000000 #####
#    10.                "GrayLevelVariance" 204.000000 #####
#    11.                "LargeAreaEmphasis" 173.000000 ###
#    12.                     "ZoneVariance" 166.000000 ###
#    13.            "SizeZoneNonUniformity" 152.000000 ##
#    14.                   "ZonePercentage" 148.000000 #
#    15.  "SizeZoneNonUniformityNormalized" 129.000000
#    16.                "SmallAreaEmphasis" 115.000000
#
# Variable Importance: SUM_SCORE:
#     1.        "HighGrayLevelZoneEmphasis" 23598.764920 ################
#     2.         "LowGrayLevelZoneEmphasis" 12418.486188 ########
#     3.   "SmallAreaHighGrayLevelEmphasis" 10871.586724 ######
#     4.    "SmallAreaLowGrayLevelEmphasis" 9546.323100 ######
#     5.   "LargeAreaHighGrayLevelEmphasis" 5207.769855 ##
#     6.           "GrayLevelNonUniformity" 4858.767007 ##
#     7.                      "ZoneEntropy" 4361.225833 ##
#     8.    "LargeAreaLowGrayLevelEmphasis" 2878.007461 #
#     9. "GrayLevelNonUniformityNormalized" 2658.280482 #
#    10.                "GrayLevelVariance" 2630.868893 #
#    11.                "LargeAreaEmphasis" 1641.938383
#    12.                     "ZoneVariance" 1511.072526
#    13.                   "ZonePercentage" 1389.095057
#    14.            "SizeZoneNonUniformity" 1338.747178
#    15.  "SizeZoneNonUniformityNormalized" 1090.281643
#    16.                "SmallAreaEmphasis" 990.089286
#
#
#
# Winner takes all: true
# Out-of-bag evaluation: accuracy:0.897367 logloss:0.258485
# Number of trees: 300
# Total number of nodes: 7436
#
# Number of nodes by tree:
# Count: 300 Average: 24.7867 StdDev: 3.69971
# Min: 15 Max: 35 Ignored: 0
# ----------------------------------------------
# [ 15, 16)  3   1.00%   1.00%
# [ 16, 17)  0   0.00%   1.00%
# [ 17, 18)  6   2.00%   3.00% #
# [ 18, 19)  0   0.00%   3.00%
# [ 19, 20) 17   5.67%   8.67% ###
# [ 20, 21)  0   0.00%   8.67%
# [ 21, 22) 40  13.33%  22.00% ######
# [ 22, 23)  0   0.00%  22.00%
# [ 23, 24) 61  20.33%  42.33% #########
# [ 24, 25)  0   0.00%  42.33%
# [ 25, 26) 67  22.33%  64.67% ##########
# [ 26, 27)  0   0.00%  64.67%
# [ 27, 28) 51  17.00%  81.67% ########
# [ 28, 29)  0   0.00%  81.67%
# [ 29, 30) 28   9.33%  91.00% ####
# [ 30, 31)  0   0.00%  91.00%
# [ 31, 32) 17   5.67%  96.67% ###
# [ 32, 33)  0   0.00%  96.67%
# [ 33, 34)  9   3.00%  99.67% #
# [ 34, 35]  1   0.33% 100.00%
#
# Depth by leafs:
# Count: 3868 Average: 4.27896 StdDev: 1.40486
# Min: 1 Max: 11 Ignored: 0
# ----------------------------------------------
# [  1,  2)   13   0.34%   0.34%
# [  2,  3)  328   8.48%   8.82% ###
# [  3,  4)  868  22.44%  31.26% ########
# [  4,  5) 1064  27.51%  58.76% ##########
# [  5,  6)  886  22.91%  81.67% ########
# [  6,  7)  454  11.74%  93.41% ####
# [  7,  8)  195   5.04%  98.45% ##
# [  8,  9)   42   1.09%  99.53%
# [  9, 10)   15   0.39%  99.92%
# [ 10, 11)    1   0.03%  99.95%
# [ 11, 11]    2   0.05% 100.00%
#
# Number of training obs by leaf:
# Count: 3868 Average: 34.9018 StdDev: 64.6407
# Min: 5 Max: 349 Ignored: 0
# ----------------------------------------------
# [   5,  22) 2755  71.23%  71.23% ##########
# [  22,  39)  300   7.76%  78.98% #
# [  39,  56)  300   7.76%  86.74% #
# [  56,  74)   80   2.07%  88.81%
# [  74,  91)   53   1.37%  90.18%
# [  91, 108)   35   0.90%  91.08%
# [ 108, 125)   17   0.44%  91.52%
# [ 125, 143)   21   0.54%  92.06%
# [ 143, 160)   18   0.47%  92.53%
# [ 160, 177)   17   0.44%  92.97%
# [ 177, 194)   22   0.57%  93.54%
# [ 194, 212)   26   0.67%  94.21%
# [ 212, 229)   41   1.06%  95.27%
# [ 229, 246)   28   0.72%  95.99%
# [ 246, 263)   49   1.27%  97.26%
# [ 263, 281)   58   1.50%  98.76%
# [ 281, 298)   24   0.62%  99.38%
# [ 298, 315)   13   0.34%  99.72%
# [ 315, 332)    7   0.18%  99.90%
# [ 332, 349]    4   0.10% 100.00%
#
# Attribute in nodes:
# 	384 : HighGrayLevelZoneEmphasis [NUMERICAL]
# 	315 : GrayLevelNonUniformity [NUMERICAL]
# 	300 : LargeAreaHighGrayLevelEmphasis [NUMERICAL]
# 	289 : SmallAreaHighGrayLevelEmphasis [NUMERICAL]
# 	274 : LowGrayLevelZoneEmphasis [NUMERICAL]
# 	241 : SmallAreaLowGrayLevelEmphasis [NUMERICAL]
# 	235 : ZoneEntropy [NUMERICAL]
# 	229 : LargeAreaLowGrayLevelEmphasis [NUMERICAL]
# 	214 : GrayLevelNonUniformityNormalized [NUMERICAL]
# 	204 : GrayLevelVariance [NUMERICAL]
# 	173 : LargeAreaEmphasis [NUMERICAL]
# 	166 : ZoneVariance [NUMERICAL]
# 	152 : SizeZoneNonUniformity [NUMERICAL]
# 	148 : ZonePercentage [NUMERICAL]
# 	129 : SizeZoneNonUniformityNormalized [NUMERICAL]
# 	115 : SmallAreaEmphasis [NUMERICAL]
#
# Attribute in nodes with depth <= 0:
# 	106 : HighGrayLevelZoneEmphasis [NUMERICAL]
# 	60 : LowGrayLevelZoneEmphasis [NUMERICAL]
# 	43 : SmallAreaLowGrayLevelEmphasis [NUMERICAL]
# 	40 : SmallAreaHighGrayLevelEmphasis [NUMERICAL]
# 	16 : LargeAreaHighGrayLevelEmphasis [NUMERICAL]
# 	13 : ZoneEntropy [NUMERICAL]
# 	10 : LargeAreaLowGrayLevelEmphasis [NUMERICAL]
# 	7 : GrayLevelNonUniformity [NUMERICAL]
# 	3 : SizeZoneNonUniformityNormalized [NUMERICAL]
# 	2 : GrayLevelNonUniformityNormalized [NUMERICAL]
#
# Attribute in nodes with depth <= 1:
# 	193 : HighGrayLevelZoneEmphasis [NUMERICAL]
# 	129 : LowGrayLevelZoneEmphasis [NUMERICAL]
# 	121 : SmallAreaHighGrayLevelEmphasis [NUMERICAL]
# 	98 : SmallAreaLowGrayLevelEmphasis [NUMERICAL]
# 	65 : GrayLevelNonUniformity [NUMERICAL]
# 	57 : ZoneEntropy [NUMERICAL]
# 	53 : LargeAreaHighGrayLevelEmphasis [NUMERICAL]
# 	47 : LargeAreaLowGrayLevelEmphasis [NUMERICAL]
# 	43 : GrayLevelVariance [NUMERICAL]
# 	43 : GrayLevelNonUniformityNormalized [NUMERICAL]
# 	11 : SizeZoneNonUniformity [NUMERICAL]
# 	10 : SmallAreaEmphasis [NUMERICAL]
# 	6 : ZonePercentage [NUMERICAL]
# 	5 : SizeZoneNonUniformityNormalized [NUMERICAL]
# 	3 : ZoneVariance [NUMERICAL]
# 	3 : LargeAreaEmphasis [NUMERICAL]
#
# Attribute in nodes with depth <= 2:
# 	263 : HighGrayLevelZoneEmphasis [NUMERICAL]
# 	183 : SmallAreaHighGrayLevelEmphasis [NUMERICAL]
# 	177 : LowGrayLevelZoneEmphasis [NUMERICAL]
# 	153 : SmallAreaLowGrayLevelEmphasis [NUMERICAL]
# 	150 : GrayLevelNonUniformity [NUMERICAL]
# 	136 : LargeAreaHighGrayLevelEmphasis [NUMERICAL]
# 	119 : ZoneEntropy [NUMERICAL]
# 	98 : GrayLevelNonUniformityNormalized [NUMERICAL]
# 	88 : LargeAreaLowGrayLevelEmphasis [NUMERICAL]
# 	84 : GrayLevelVariance [NUMERICAL]
# 	54 : ZonePercentage [NUMERICAL]
# 	53 : LargeAreaEmphasis [NUMERICAL]
# 	52 : ZoneVariance [NUMERICAL]
# 	51 : SizeZoneNonUniformity [NUMERICAL]
# 	40 : SizeZoneNonUniformityNormalized [NUMERICAL]
# 	32 : SmallAreaEmphasis [NUMERICAL]
#
# Attribute in nodes with depth <= 3:
# 	315 : HighGrayLevelZoneEmphasis [NUMERICAL]
# 	231 : GrayLevelNonUniformity [NUMERICAL]
# 	226 : SmallAreaHighGrayLevelEmphasis [NUMERICAL]
# 	217 : LargeAreaHighGrayLevelEmphasis [NUMERICAL]
# 	207 : LowGrayLevelZoneEmphasis [NUMERICAL]
# 	193 : SmallAreaLowGrayLevelEmphasis [NUMERICAL]
# 	168 : GrayLevelNonUniformityNormalized [NUMERICAL]
# 	165 : ZoneEntropy [NUMERICAL]
# 	149 : LargeAreaLowGrayLevelEmphasis [NUMERICAL]
# 	139 : GrayLevelVariance [NUMERICAL]
# 	109 : ZoneVariance [NUMERICAL]
# 	104 : LargeAreaEmphasis [NUMERICAL]
# 	98 : ZonePercentage [NUMERICAL]
# 	88 : SizeZoneNonUniformity [NUMERICAL]
# 	76 : SizeZoneNonUniformityNormalized [NUMERICAL]
# 	72 : SmallAreaEmphasis [NUMERICAL]
#
# Attribute in nodes with depth <= 5:
# 	374 : HighGrayLevelZoneEmphasis [NUMERICAL]
# 	306 : GrayLevelNonUniformity [NUMERICAL]
# 	290 : LargeAreaHighGrayLevelEmphasis [NUMERICAL]
# 	282 : SmallAreaHighGrayLevelEmphasis [NUMERICAL]
# 	261 : LowGrayLevelZoneEmphasis [NUMERICAL]
# 	239 : SmallAreaLowGrayLevelEmphasis [NUMERICAL]
# 	228 : ZoneEntropy [NUMERICAL]
# 	214 : LargeAreaLowGrayLevelEmphasis [NUMERICAL]
# 	204 : GrayLevelNonUniformityNormalized [NUMERICAL]
# 	194 : GrayLevelVariance [NUMERICAL]
# 	164 : LargeAreaEmphasis [NUMERICAL]
# 	160 : ZoneVariance [NUMERICAL]
# 	137 : ZonePercentage [NUMERICAL]
# 	136 : SizeZoneNonUniformity [NUMERICAL]
# 	126 : SizeZoneNonUniformityNormalized [NUMERICAL]
# 	108 : SmallAreaEmphasis [NUMERICAL]
#
# Condition type in nodes:
# 	3568 : HigherCondition
# Condition type in nodes with depth <= 0:
# 	300 : HigherCondition
# Condition type in nodes with depth <= 1:
# 	887 : HigherCondition
# Condition type in nodes with depth <= 2:
# 	1733 : HigherCondition
# Condition type in nodes with depth <= 3:
# 	2557 : HigherCondition
# Condition type in nodes with depth <= 5:
# 	3423 : HigherCondition
# Node format: NOT_SET
#
# Training OOB:
# 	trees: 1, Out-of-bag evaluation: accuracy:0.929014 logloss:2.55861
# 	trees: 12, Out-of-bag evaluation: accuracy:0.89396 logloss:2.08484
# 	trees: 22, Out-of-bag evaluation: accuracy:0.886087 logloss:0.80839
# 	trees: 32, Out-of-bag evaluation: accuracy:0.897367 logloss:0.553887
# 	trees: 43, Out-of-bag evaluation: accuracy:0.897367 logloss:0.552869
# 	trees: 53, Out-of-bag evaluation: accuracy:0.902102 logloss:0.508251
# 	trees: 63, Out-of-bag evaluation: accuracy:0.900793 logloss:0.508745
# 	trees: 73, Out-of-bag evaluation: accuracy:0.896058 logloss:0.514202
# 	trees: 84, Out-of-bag evaluation: accuracy:0.896058 logloss:0.515368
# 	trees: 94, Out-of-bag evaluation: accuracy:0.894749 logloss:0.515329
# 	trees: 104, Out-of-bag evaluation: accuracy:0.896058 logloss:0.509483
# 	trees: 114, Out-of-bag evaluation: accuracy:0.897367 logloss:0.268893
# 	trees: 124, Out-of-bag evaluation: accuracy:0.898676 logloss:0.271341
# 	trees: 135, Out-of-bag evaluation: accuracy:0.897367 logloss:0.266664
# 	trees: 145, Out-of-bag evaluation: accuracy:0.898676 logloss:0.268624
# 	trees: 157, Out-of-bag evaluation: accuracy:0.898676 logloss:0.265368
# 	trees: 167, Out-of-bag evaluation: accuracy:0.899985 logloss:0.267347
# 	trees: 178, Out-of-bag evaluation: accuracy:0.899985 logloss:0.266363
# 	trees: 188, Out-of-bag evaluation: accuracy:0.899985 logloss:0.265585
# 	trees: 198, Out-of-bag evaluation: accuracy:0.898676 logloss:0.266379
# 	trees: 208, Out-of-bag evaluation: accuracy:0.897367 logloss:0.268419
# 	trees: 218, Out-of-bag evaluation: accuracy:0.897367 logloss:0.270786
# 	trees: 228, Out-of-bag evaluation: accuracy:0.897367 logloss:0.269181
# 	trees: 239, Out-of-bag evaluation: accuracy:0.897367 logloss:0.265104
# 	trees: 250, Out-of-bag evaluation: accuracy:0.896058 logloss:0.263996
# 	trees: 261, Out-of-bag evaluation: accuracy:0.898676 logloss:0.264002
# 	trees: 271, Out-of-bag evaluation: accuracy:0.896058 logloss:0.26398
# 	trees: 281, Out-of-bag evaluation: accuracy:0.896058 logloss:0.258249
# 	trees: 291, Out-of-bag evaluation: accuracy:0.897367 logloss:0.25875
# 	trees: 300, Out-of-bag evaluation: accuracy:0.897367 logloss:0.258485

# %%
# Model features
model.make_inspector().features()
# Out:
# ["GrayLevelNonUniformity" (1; #0),
#  "GrayLevelNonUniformityNormalized" (1; #1),
#  "GrayLevelVariance" (1; #2),
#  "HighGrayLevelZoneEmphasis" (1; #3),
#  "LargeAreaEmphasis" (1; #4),
#  "LargeAreaHighGrayLevelEmphasis" (1; #5),
#  "LargeAreaLowGrayLevelEmphasis" (1; #6),
#  "LowGrayLevelZoneEmphasis" (1; #7),
#  "SizeZoneNonUniformity" (1; #8),
#  "SizeZoneNonUniformityNormalized" (1; #9),
#  "SmallAreaEmphasis" (1; #10),
#  "SmallAreaHighGrayLevelEmphasis" (1; #11),
#  "SmallAreaLowGrayLevelEmphasis" (1; #12),
#  "ZoneEntropy" (1; #13),
#  "ZonePercentage" (1; #14),
#  "ZoneVariance" (1; #15)]

# %%
# Feature importance
model.make_inspector().variable_importances()
# Out:
# {'INV_MEAN_MIN_DEPTH': [("HighGrayLevelZoneEmphasis" (1; #3),
#    0.3097994346856331),
#   ("SmallAreaHighGrayLevelEmphasis" (1; #11), 0.2506986491794798),
#   ("LowGrayLevelZoneEmphasis" (1; #7), 0.2502678856513952),
#   ("SmallAreaLowGrayLevelEmphasis" (1; #12), 0.23423948108903425),
#   ("LargeAreaHighGrayLevelEmphasis" (1; #5), 0.23227410041294524),
#   ("GrayLevelNonUniformity" (1; #0), 0.23211722964894832),
#   ("ZoneEntropy" (1; #13), 0.22386070532017224),
#   ("LargeAreaLowGrayLevelEmphasis" (1; #6), 0.21236714931603745),
#   ("GrayLevelNonUniformityNormalized" (1; #1), 0.2099690293882247),
#   ("GrayLevelVariance" (1; #2), 0.20987565345961517),
#   ("LargeAreaEmphasis" (1; #4), 0.20308390767600168),
#   ("ZoneVariance" (1; #15), 0.20269314771953437),
#   ("ZonePercentage" (1; #14), 0.2008544155863876),
#   ("SizeZoneNonUniformity" (1; #8), 0.2000998337070014),
#   ("SizeZoneNonUniformityNormalized" (1; #9), 0.19927499634590365),
#   ("SmallAreaEmphasis" (1; #10), 0.19765659116806295)],
#  'SUM_SCORE': [("HighGrayLevelZoneEmphasis" (1; #3), 23598.764920209458),
#   ("LowGrayLevelZoneEmphasis" (1; #7), 12418.486188138497),
#   ("SmallAreaHighGrayLevelEmphasis" (1; #11), 10871.586723544273),
#   ("SmallAreaLowGrayLevelEmphasis" (1; #12), 9546.323100225103),
#   ("LargeAreaHighGrayLevelEmphasis" (1; #5), 5207.769854594929),
#   ("GrayLevelNonUniformity" (1; #0), 4858.76700744519),
#   ("ZoneEntropy" (1; #13), 4361.225832810909),
#   ("LargeAreaLowGrayLevelEmphasis" (1; #6), 2878.0074605713326),
#   ("GrayLevelNonUniformityNormalized" (1; #1), 2658.280482178684),
#   ("GrayLevelVariance" (1; #2), 2630.868893447385),
#   ("LargeAreaEmphasis" (1; #4), 1641.9383825544976),
#   ("ZoneVariance" (1; #15), 1511.0725257546499),
#   ("ZonePercentage" (1; #14), 1389.0950569102079),
#   ("SizeZoneNonUniformity" (1; #8), 1338.747177841992),
#   ("SizeZoneNonUniformityNormalized" (1; #9), 1090.2816430813327),
#   ("SmallAreaEmphasis" (1; #10), 990.0892858256581)],
#  'NUM_AS_ROOT': [("HighGrayLevelZoneEmphasis" (1; #3), 106.0),
#   ("LowGrayLevelZoneEmphasis" (1; #7), 60.0),
#   ("SmallAreaLowGrayLevelEmphasis" (1; #12), 43.0),
#   ("SmallAreaHighGrayLevelEmphasis" (1; #11), 40.0),
#   ("LargeAreaHighGrayLevelEmphasis" (1; #5), 16.0),
#   ("ZoneEntropy" (1; #13), 13.0),
#   ("LargeAreaLowGrayLevelEmphasis" (1; #6), 10.0),
#   ("GrayLevelNonUniformity" (1; #0), 7.0),
#   ("SizeZoneNonUniformityNormalized" (1; #9), 3.0),
#   ("GrayLevelNonUniformityNormalized" (1; #1), 2.0)],
#  'NUM_NODES': [("HighGrayLevelZoneEmphasis" (1; #3), 384.0),
#   ("GrayLevelNonUniformity" (1; #0), 315.0),
#   ("LargeAreaHighGrayLevelEmphasis" (1; #5), 300.0),
#   ("SmallAreaHighGrayLevelEmphasis" (1; #11), 289.0),
#   ("LowGrayLevelZoneEmphasis" (1; #7), 274.0),
#   ("SmallAreaLowGrayLevelEmphasis" (1; #12), 241.0),
#   ("ZoneEntropy" (1; #13), 235.0),
#   ("LargeAreaLowGrayLevelEmphasis" (1; #6), 229.0),
#   ("GrayLevelNonUniformityNormalized" (1; #1), 214.0),
#   ("GrayLevelVariance" (1; #2), 204.0),
#   ("LargeAreaEmphasis" (1; #4), 173.0),
#   ("ZoneVariance" (1; #15), 166.0),
#   ("SizeZoneNonUniformity" (1; #8), 152.0),
#   ("ZonePercentage" (1; #14), 148.0),
#   ("SizeZoneNonUniformityNormalized" (1; #9), 129.0),
#   ("SmallAreaEmphasis" (1; #10), 115.0)]}

# %%
# Model self evaluation
model.make_inspector().evaluation()
# Out:
# Evaluation(num_examples=450, accuracy=0.8973667992625406, loss=0.2584853553481058, rmse=None, ndcg=None, aucs=None, auuc=None, qini=None)

# %%
logs = model.make_inspector().training_logs()

plt.figure(figsize=(12, 4))
plt.subplot(1, 2, 1)
plt.plot([log.num_trees for log in logs], [log.evaluation.accuracy for log in logs])
plt.xlabel("Number of trees")
plt.ylabel("Accuracy (out-of-bag)")
plt.subplot(1, 2, 2)
plt.plot([log.num_trees for log in logs], [log.evaluation.loss for log in logs])
plt.xlabel("Number of trees")
plt.ylabel("Logloss (out-of-bag)")
plt.show()

# %% [markdown]
# Calculate the score of our hold-out validation dataset

# %%
predictions = model.predict(val_ds)
y_true      = validation_data["label"]

from sklearn.metrics import roc_auc_score
ROC_AUC = roc_auc_score(y_true, predictions)
print("The ROC AUC score is %.5f" % ROC_AUC )
# Out:
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 60ms/step
# The ROC AUC score is 1.00000

# %%
# Compute binary classification metrics with sklearn
import numpy as np
from sklearn.metrics import (
    accuracy_score,
    precision_score,
    recall_score,
    f1_score,
    roc_auc_score,
    average_precision_score,
    confusion_matrix,
    classification_report,
    matthews_corrcoef,
    log_loss,
    brier_score_loss,
)

# Get predictions (probabilities or class labels)
preds = model.predict(test_ds)
# If model outputs probabilities, convert to labels by threshold 0.5
if preds.ndim == 2:
    # For TFDF classification, preds may be class probabilities with shape (N, 2)
    if preds.shape[1] == 2:
        pos_probs = preds[:, 1]
    else:
        # If single-probability column (positive class)
        pos_probs = preds[:, -1]
    y_pred = (pos_probs >= 0.5).astype(int)
else:
    # Already class labels
    y_pred = preds.astype(int)
    pos_probs = None

# Ground truth labels (must be 0/1 integers)
y_true = test_data["label"].astype(int).to_numpy()

# Core metrics
metrics = {}
metrics["accuracy"] = accuracy_score(y_true, y_pred)
metrics["precision"] = precision_score(y_true, y_pred, zero_division=0)
metrics["recall"] = recall_score(y_true, y_pred, zero_division=0)
metrics["f1"] = f1_score(y_true, y_pred, zero_division=0)
metrics["mcc"] = matthews_corrcoef(y_true, y_pred)

# Probabilistic metrics (only if we have probabilities)
if pos_probs is not None:
    metrics["roc_auc"] = roc_auc_score(y_true, pos_probs)
    metrics["pr_auc"] = average_precision_score(y_true, pos_probs)
    metrics["log_loss"] = log_loss(y_true, pos_probs, labels=[0,1])
    metrics["brier_score"] = brier_score_loss(y_true, pos_probs)

# Confusion matrix and detailed report
cm = confusion_matrix(y_true, y_pred, labels=[0,1])
report = classification_report(y_true, y_pred, digits=4)

print("Sklearn binary metrics:")
for k, v in metrics.items():
    print(f"{k}: {v:.4f}")
print("\nConfusion matrix:\n", cm)
print("\nClassification report:\n", report)
# Out:
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 64ms/step
# Sklearn binary metrics:
# accuracy: 0.9302
# precision: 0.8182
# recall: 0.5625
# f1: 0.6667
# mcc: 0.6430
# roc_auc: 0.9416
# pr_auc: 0.6761
# log_loss: 0.2154
# brier_score: 0.0634
#
# Confusion matrix:
#  [[111   2]
#  [  7   9]]
#
# Classification report:
#                precision    recall  f1-score   support
#
#            0     0.9407    0.9823    0.9610       113
#            1     0.8182    0.5625    0.6667        16
#
#     accuracy                         0.9302       129
#    macro avg     0.8794    0.7724    0.8139       129
# weighted avg     0.9255    0.9302    0.9245       129
