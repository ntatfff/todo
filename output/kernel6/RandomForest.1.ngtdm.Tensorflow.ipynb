# %%
# Import packages and modules
import numpy  as np
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow_decision_forests as tfdf

from sklearn.model_selection import train_test_split
# Out:
# 2026-08-12 05:59:51.458122: I tensorflow/core/util/port.cc:113] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2026-08-12 05:59:51.802752: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2026-08-12 05:59:56.465824: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
# Check the version of TensorFlow Decision Forests
print("Found TensorFlow Decision Forests v" + tfdf.__version__)
# Out:
# Found TensorFlow Decision Forests v1.9.1

# %%
datasetPath = 'dataset/firstorder/kernel5-radius5/dataset.csv'

# %%
# Parameters
datasetPath = "dataset/ngtdm/kernel6-radius6/1.dataset.csv"

# %%
# train/validation/test = 70/10/20
dataset = pd.read_csv(datasetPath)

train_data, temp_data = train_test_split(dataset, test_size=0.3, random_state=42)
validation_data, test_data = train_test_split(temp_data, test_size=2/3, random_state=42)

# %%
from sklearn.utils.class_weight import compute_class_weight

# tinh class weight tren tap train
classes = np.array([0, 1])
weights = compute_class_weight(class_weight="balanced", classes=classes, y=train_data["label"])
class_weight = {0: weights[0], 1: weights[1]}

# gan sample_weight cho tung dong
train_data["sample_weight"] = train_data["label"].map(class_weight)
validation_data["sample_weight"] = validation_data["label"].map(class_weight)
test_data["sample_weight"] = test_data["label"].map(class_weight)

# Convert the dataset into a TensorFlow dataset.
train_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    train_data, label="label", weight="sample_weight"
)         
val_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    validation_data, label="label", weight="sample_weight"
)
test_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    test_data, label="label", weight="sample_weight"
)
# Out:
# 2026-08-12 06:00:11.933685: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:984] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2026-08-12 06:00:11.935200: W tensorflow/core/common_runtime/gpu/gpu_device.cc:2251] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...

# %%
import keras

# %%
# %%time

# Train a Random Forest model.
model = tfdf.keras.RandomForestModel()

# Add evaluation metrics
model.compile(
    metrics=["accuracy"]
)
model.fit(x=train_ds)

# # Train a Gradient Boosted Trees model.
# model = tfdf.keras.GradientBoostedTreesModel(num_trees=1500)
# model.fit(train_ds)
# Out:
# Use /tmp/tmpk46go14q as temporary training directory
# Reading training dataset...
# Training dataset read in 0:00:02.377170. Found 450 examples.
# Training model...
# Model trained in 0:00:00.049264
# Compiling model...
# [INFO 26-08-12 06:00:14.4974 UTC kernel.cc:1233] Loading model from path /tmp/tmpk46go14q/model/ with prefix afc7ba057b1941ee
# [INFO 26-08-12 06:00:14.5072 UTC decision_forest.cc:734] Model loaded with 300 root(s), 7588 node(s), and 5 input feature(s).
# [INFO 26-08-12 06:00:14.5072 UTC abstract_model.cc:1362] Engine "RandomForestOptPred" built
# [INFO 26-08-12 06:00:14.5073 UTC kernel.cc:1061] Use fast generic engine
# Model compiled.
# CPU times: user 5.53 s, sys: 16.4 ms, total: 5.55 s
# Wall time: 5.41 s

# %%
# Evaluate the model
evaluate = model.evaluate(val_ds, return_dict=True)
print()

for name, value in evaluate.items():
    print(f"{name}: {value:.4f}")
# Out:
# WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 1/1 [==============================] - ETA: 0s - loss: 0.0000e+00 - accuracy: 0.9062
# 1/1 [==============================] - 3s 3s/step - loss: 0.0000e+00 - accuracy: 0.9062
# loss: 0.0000
# accuracy: 0.9062

# %%
# Model Summary
model.summary()
# Out:
# Model: "random_forest_model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
# =================================================================
# Total params: 1 (1.00 Byte)
# Trainable params: 0 (0.00 Byte)
# Non-trainable params: 1 (1.00 Byte)
# _________________________________________________________________
# Type: "RANDOM_FOREST"
# Task: CLASSIFICATION
# Label: "__LABEL"
#
# Input Features (5):
# 	Busyness
# 	Coarseness
# 	Complexity
# 	Contrast
# 	Strength
#
# Trained with weights
#
# Variable Importance: INV_MEAN_MIN_DEPTH:
#     1.   "Busyness"  0.695212 ################
#     2. "Coarseness"  0.323667 ###
#     3. "Complexity"  0.251544
#     4.   "Strength"  0.239914
#     5.   "Contrast"  0.232893
#
# Variable Importance: NUM_AS_ROOT:
#     1.   "Busyness" 228.000000 ################
#     2. "Coarseness" 72.000000
#
# Variable Importance: NUM_NODES:
#     1.   "Busyness" 1182.000000 ################
#     2. "Complexity" 697.000000 ####
#     3. "Coarseness" 665.000000 ###
#     4.   "Strength" 575.000000 #
#     5.   "Contrast" 525.000000
#
# Variable Importance: SUM_SCORE:
#     1.   "Busyness" 49774.214568 ################
#     2. "Coarseness" 15449.648881 ###
#     3. "Complexity" 7568.775561
#     4.   "Strength" 6759.520235
#     5.   "Contrast" 5521.978403
#
#
#
# Winner takes all: true
# Out-of-bag evaluation: accuracy:0.88275 logloss:0.350367
# Number of trees: 300
# Total number of nodes: 7588
#
# Number of nodes by tree:
# Count: 300 Average: 25.2933 StdDev: 3.93539
# Min: 15 Max: 41 Ignored: 0
# ----------------------------------------------
# [ 15, 16)  2   0.67%   0.67%
# [ 16, 17)  0   0.00%   0.67%
# [ 17, 19)  5   1.67%   2.33% #
# [ 19, 20) 18   6.00%   8.33% ###
# [ 20, 21)  0   0.00%   8.33%
# [ 21, 23) 33  11.00%  19.33% #####
# [ 23, 24) 57  19.00%  38.33% #########
# [ 24, 25)  0   0.00%  38.33%
# [ 25, 27) 61  20.33%  58.67% ##########
# [ 27, 28) 49  16.33%  75.00% ########
# [ 28, 29)  0   0.00%  75.00%
# [ 29, 31) 46  15.33%  90.33% ########
# [ 31, 32) 15   5.00%  95.33% ##
# [ 32, 33)  0   0.00%  95.33%
# [ 33, 35)  9   3.00%  98.33% #
# [ 35, 36)  3   1.00%  99.33%
# [ 36, 37)  0   0.00%  99.33%
# [ 37, 39)  1   0.33%  99.67%
# [ 39, 40)  0   0.00%  99.67%
# [ 40, 41]  1   0.33% 100.00%
#
# Depth by leafs:
# Count: 3944 Average: 4.11105 StdDev: 1.10908
# Min: 1 Max: 10 Ignored: 0
# ----------------------------------------------
# [  1,  2)    6   0.15%   0.15%
# [  2,  3)  221   5.60%   5.76% ##
# [  3,  4)  941  23.86%  29.61% #######
# [  4,  5) 1399  35.47%  65.09% ##########
# [  5,  6) 1014  25.71%  90.80% #######
# [  6,  7)  287   7.28%  98.07% ##
# [  7,  8)   58   1.47%  99.54%
# [  8,  9)   15   0.38%  99.92%
# [  9, 10)    1   0.03%  99.95%
# [ 10, 10]    2   0.05% 100.00%
#
# Number of training obs by leaf:
# Count: 3944 Average: 34.2292 StdDev: 74.3674
# Min: 5 Max: 362 Ignored: 0
# ----------------------------------------------
# [   5,  22) 2991  75.84%  75.84% ##########
# [  22,  40)  412  10.45%  86.28% #
# [  40,  58)  128   3.25%  89.53%
# [  58,  76)   69   1.75%  91.28%
# [  76,  94)   12   0.30%  91.58%
# [  94, 112)   10   0.25%  91.84%
# [ 112, 130)   15   0.38%  92.22%
# [ 130, 148)    5   0.13%  92.34%
# [ 148, 166)    3   0.08%  92.42%
# [ 166, 184)    2   0.05%  92.47%
# [ 184, 201)    9   0.23%  92.70%
# [ 201, 219)    8   0.20%  92.90%
# [ 219, 237)   10   0.25%  93.15%
# [ 237, 255)   26   0.66%  93.81%
# [ 255, 273)   46   1.17%  94.98%
# [ 273, 291)   55   1.39%  96.37%
# [ 291, 309)   62   1.57%  97.95%
# [ 309, 327)   40   1.01%  98.96%
# [ 327, 345)   26   0.66%  99.62%
# [ 345, 362]   15   0.38% 100.00%
#
# Attribute in nodes:
# 	1182 : Busyness [NUMERICAL]
# 	697 : Complexity [NUMERICAL]
# 	665 : Coarseness [NUMERICAL]
# 	575 : Strength [NUMERICAL]
# 	525 : Contrast [NUMERICAL]
#
# Attribute in nodes with depth <= 0:
# 	228 : Busyness [NUMERICAL]
# 	72 : Coarseness [NUMERICAL]
#
# Attribute in nodes with depth <= 1:
# 	471 : Busyness [NUMERICAL]
# 	199 : Coarseness [NUMERICAL]
# 	90 : Complexity [NUMERICAL]
# 	68 : Strength [NUMERICAL]
# 	66 : Contrast [NUMERICAL]
#
# Attribute in nodes with depth <= 2:
# 	770 : Busyness [NUMERICAL]
# 	335 : Complexity [NUMERICAL]
# 	332 : Coarseness [NUMERICAL]
# 	235 : Strength [NUMERICAL]
# 	189 : Contrast [NUMERICAL]
#
# Attribute in nodes with depth <= 3:
# 	1000 : Busyness [NUMERICAL]
# 	539 : Complexity [NUMERICAL]
# 	513 : Coarseness [NUMERICAL]
# 	437 : Strength [NUMERICAL]
# 	365 : Contrast [NUMERICAL]
#
# Attribute in nodes with depth <= 5:
# 	1175 : Busyness [NUMERICAL]
# 	687 : Complexity [NUMERICAL]
# 	658 : Coarseness [NUMERICAL]
# 	564 : Strength [NUMERICAL]
# 	517 : Contrast [NUMERICAL]
#
# Condition type in nodes:
# 	3644 : HigherCondition
# Condition type in nodes with depth <= 0:
# 	300 : HigherCondition
# Condition type in nodes with depth <= 1:
# 	894 : HigherCondition
# Condition type in nodes with depth <= 2:
# 	1861 : HigherCondition
# Condition type in nodes with depth <= 3:
# 	2854 : HigherCondition
# Condition type in nodes with depth <= 5:
# 	3601 : HigherCondition
# Node format: NOT_SET
#
# Training OOB:
# 	trees: 1, Out-of-bag evaluation: accuracy:0.81274 logloss:6.74952
# 	trees: 12, Out-of-bag evaluation: accuracy:0.850838 logloss:4.94232
# 	trees: 23, Out-of-bag evaluation: accuracy:0.857279 logloss:2.30724
# 	trees: 33, Out-of-bag evaluation: accuracy:0.871284 logloss:1.32969
# 	trees: 43, Out-of-bag evaluation: accuracy:0.87636 logloss:1.32274
# 	trees: 55, Out-of-bag evaluation: accuracy:0.87636 logloss:1.01245
# 	trees: 65, Out-of-bag evaluation: accuracy:0.877629 logloss:0.968332
# 	trees: 75, Out-of-bag evaluation: accuracy:0.885288 logloss:0.968628
# 	trees: 85, Out-of-bag evaluation: accuracy:0.885288 logloss:0.677093
# 	trees: 95, Out-of-bag evaluation: accuracy:0.884019 logloss:0.682906
# 	trees: 105, Out-of-bag evaluation: accuracy:0.884019 logloss:0.388264
# 	trees: 116, Out-of-bag evaluation: accuracy:0.88275 logloss:0.393073
# 	trees: 126, Out-of-bag evaluation: accuracy:0.885288 logloss:0.394046
# 	trees: 136, Out-of-bag evaluation: accuracy:0.88275 logloss:0.395398
# 	trees: 146, Out-of-bag evaluation: accuracy:0.881481 logloss:0.397399
# 	trees: 158, Out-of-bag evaluation: accuracy:0.872553 logloss:0.392951
# 	trees: 168, Out-of-bag evaluation: accuracy:0.872553 logloss:0.352455
# 	trees: 178, Out-of-bag evaluation: accuracy:0.88275 logloss:0.355357
# 	trees: 188, Out-of-bag evaluation: accuracy:0.88275 logloss:0.355923
# 	trees: 199, Out-of-bag evaluation: accuracy:0.88275 logloss:0.352195
# 	trees: 209, Out-of-bag evaluation: accuracy:0.881481 logloss:0.35349
# 	trees: 219, Out-of-bag evaluation: accuracy:0.881481 logloss:0.357014
# 	trees: 229, Out-of-bag evaluation: accuracy:0.881481 logloss:0.354368
# 	trees: 239, Out-of-bag evaluation: accuracy:0.881481 logloss:0.35546
# 	trees: 249, Out-of-bag evaluation: accuracy:0.88275 logloss:0.35031
# 	trees: 260, Out-of-bag evaluation: accuracy:0.88275 logloss:0.352178
# 	trees: 270, Out-of-bag evaluation: accuracy:0.88275 logloss:0.348333
# 	trees: 280, Out-of-bag evaluation: accuracy:0.875091 logloss:0.349745
# 	trees: 290, Out-of-bag evaluation: accuracy:0.875091 logloss:0.349154
# 	trees: 300, Out-of-bag evaluation: accuracy:0.88275 logloss:0.350367

# %%
# Model features
model.make_inspector().features()
# Out:
# ["Busyness" (1; #0),
#  "Coarseness" (1; #1),
#  "Complexity" (1; #2),
#  "Contrast" (1; #3),
#  "Strength" (1; #4)]

# %%
# Feature importance
model.make_inspector().variable_importances()
# Out:
# {'INV_MEAN_MIN_DEPTH': [("Busyness" (1; #0), 0.6952115410923769),
#   ("Coarseness" (1; #1), 0.3236671787005612),
#   ("Complexity" (1; #2), 0.25154401063257087),
#   ("Strength" (1; #4), 0.239914430016207),
#   ("Contrast" (1; #3), 0.23289323595750783)],
#  'NUM_AS_ROOT': [("Busyness" (1; #0), 228.0), ("Coarseness" (1; #1), 72.0)],
#  'SUM_SCORE': [("Busyness" (1; #0), 49774.214567725896),
#   ("Coarseness" (1; #1), 15449.648881494042),
#   ("Complexity" (1; #2), 7568.775561212001),
#   ("Strength" (1; #4), 6759.520234650294),
#   ("Contrast" (1; #3), 5521.978403332319)],
#  'NUM_NODES': [("Busyness" (1; #0), 1182.0),
#   ("Complexity" (1; #2), 697.0),
#   ("Coarseness" (1; #1), 665.0),
#   ("Strength" (1; #4), 575.0),
#   ("Contrast" (1; #3), 525.0)]}

# %%
# Model self evaluation
model.make_inspector().evaluation()
# Out:
# Evaluation(num_examples=450, accuracy=0.8827501800532532, loss=0.3503666024723785, rmse=None, ndcg=None, aucs=None, auuc=None, qini=None)

# %%
logs = model.make_inspector().training_logs()

plt.figure(figsize=(12, 4))
plt.subplot(1, 2, 1)
plt.plot([log.num_trees for log in logs], [log.evaluation.accuracy for log in logs])
plt.xlabel("Number of trees")
plt.ylabel("Accuracy (out-of-bag)")
plt.subplot(1, 2, 2)
plt.plot([log.num_trees for log in logs], [log.evaluation.loss for log in logs])
plt.xlabel("Number of trees")
plt.ylabel("Logloss (out-of-bag)")
plt.show()

# %% [markdown]
# Calculate the score of our hold-out validation dataset

# %%
predictions = model.predict(val_ds)
y_true      = validation_data["label"]

from sklearn.metrics import roc_auc_score
ROC_AUC = roc_auc_score(y_true, predictions)
print("The ROC AUC score is %.5f" % ROC_AUC )
# Out:
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 53ms/step
# The ROC AUC score is 0.98498

# %%
# Compute binary classification metrics with sklearn
import numpy as np
from sklearn.metrics import (
    accuracy_score,
    precision_score,
    recall_score,
    f1_score,
    roc_auc_score,
    average_precision_score,
    confusion_matrix,
    classification_report,
    matthews_corrcoef,
    log_loss,
    brier_score_loss,
)

# Get predictions (probabilities or class labels)
preds = model.predict(test_ds)
# If model outputs probabilities, convert to labels by threshold 0.5
if preds.ndim == 2:
    # For TFDF classification, preds may be class probabilities with shape (N, 2)
    if preds.shape[1] == 2:
        pos_probs = preds[:, 1]
    else:
        # If single-probability column (positive class)
        pos_probs = preds[:, -1]
    y_pred = (pos_probs >= 0.5).astype(int)
else:
    # Already class labels
    y_pred = preds.astype(int)
    pos_probs = None

# Ground truth labels (must be 0/1 integers)
y_true = test_data["label"].astype(int).to_numpy()

# Core metrics
metrics = {}
metrics["accuracy"] = accuracy_score(y_true, y_pred)
metrics["precision"] = precision_score(y_true, y_pred, zero_division=0)
metrics["recall"] = recall_score(y_true, y_pred, zero_division=0)
metrics["f1"] = f1_score(y_true, y_pred, zero_division=0)
metrics["mcc"] = matthews_corrcoef(y_true, y_pred)

# Probabilistic metrics (only if we have probabilities)
if pos_probs is not None:
    metrics["roc_auc"] = roc_auc_score(y_true, pos_probs)
    metrics["pr_auc"] = average_precision_score(y_true, pos_probs)
    metrics["log_loss"] = log_loss(y_true, pos_probs, labels=[0,1])
    metrics["brier_score"] = brier_score_loss(y_true, pos_probs)

# Confusion matrix and detailed report
cm = confusion_matrix(y_true, y_pred, labels=[0,1])
report = classification_report(y_true, y_pred, digits=4)

print("Sklearn binary metrics:")
for k, v in metrics.items():
    print(f"{k}: {v:.4f}")
print("\nConfusion matrix:\n", cm)
print("\nClassification report:\n", report)
# Out:
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 56ms/step
# Sklearn binary metrics:
# accuracy: 0.9380
# precision: 0.7647
# recall: 0.7647
# f1: 0.7647
# mcc: 0.7290
# roc_auc: 0.9559
# pr_auc: 0.8088
# log_loss: 0.1858
# brier_score: 0.0529
#
# Confusion matrix:
#  [[108   4]
#  [  4  13]]
#
# Classification report:
#                precision    recall  f1-score   support
#
#            0     0.9643    0.9643    0.9643       112
#            1     0.7647    0.7647    0.7647        17
#
#     accuracy                         0.9380       129
#    macro avg     0.8645    0.8645    0.8645       129
# weighted avg     0.9380    0.9380    0.9380       129
