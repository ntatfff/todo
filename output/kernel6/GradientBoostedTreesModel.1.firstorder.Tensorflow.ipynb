# %%
# Import packages and modules
import numpy  as np
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow_decision_forests as tfdf

from sklearn.model_selection import train_test_split
# Out:
# 2026-08-10 17:14:07.516789: I tensorflow/core/util/port.cc:113] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2026-08-10 17:14:07.919861: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2026-08-10 17:14:13.017334: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
# Check the version of TensorFlow Decision Forests
print("Found TensorFlow Decision Forests v" + tfdf.__version__)
# Out:
# Found TensorFlow Decision Forests v1.9.1

# %%
datasetPath = 'dataset/firstorder/kernel5-radius5/dataset.csv'

# %%
# Parameters
datasetPath = "dataset/firstorder/kernel6-radius6/dataset.1p.csv"

# %%
# train/validation/test = 70/10/20
dataset = pd.read_csv(datasetPath)

train_data, temp_data = train_test_split(dataset, test_size=0.3, random_state=42)
validation_data, test_data = train_test_split(temp_data, test_size=2/3, random_state=42)

# %%
from sklearn.utils.class_weight import compute_class_weight

# tinh class weight tren tap train
classes = np.array([0, 1])
weights = compute_class_weight(class_weight="balanced", classes=classes, y=train_data["label"])
class_weight = {0: weights[0], 1: weights[1]}

# gan sample_weight cho tung dong
train_data["sample_weight"] = train_data["label"].map(class_weight)
validation_data["sample_weight"] = validation_data["label"].map(class_weight)
test_data["sample_weight"] = test_data["label"].map(class_weight)

# Convert the dataset into a TensorFlow dataset.
train_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    train_data, label="label", weight="sample_weight"
)         
val_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    validation_data, label="label", weight="sample_weight"
)
test_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    test_data, label="label", weight="sample_weight"
)
# Out:
# 2026-08-10 17:14:28.347304: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:984] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2026-08-10 17:14:28.348739: W tensorflow/core/common_runtime/gpu/gpu_device.cc:2251] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...

# %%
import keras

# %%
# %%time

# Train a Gradient Boosted Trees model.
model = tfdf.keras.GradientBoostedTreesModel()

# Add evaluation metrics
model.compile(
    metrics=["accuracy"]
)
model.fit(x=train_ds)

# # Train a Gradient Boosted Trees model.
# model = tfdf.keras.GradientBoostedTreesModel(num_trees=1500)
# model.fit(train_ds)
# Out:
# Use /tmp/tmp1avgwb8w as temporary training directory
# Reading training dataset...
# [WARNING 26-08-10 17:14:28.4915 UTC gradient_boosted_trees.cc:1840] "goss_alpha" set but "sampling_method" not equal to "GOSS".
# [WARNING 26-08-10 17:14:28.4918 UTC gradient_boosted_trees.cc:1851] "goss_beta" set but "sampling_method" not equal to "GOSS".
# [WARNING 26-08-10 17:14:28.4918 UTC gradient_boosted_trees.cc:1865] "selective_gradient_boosting_ratio" set but "sampling_method" not equal to "SELGB".
# Training dataset read in 0:00:02.469895. Found 777 examples.
# Training model...
# Model trained in 0:00:01.075291
# Compiling model...
# [INFO 26-08-10 17:14:32.0541 UTC kernel.cc:1233] Loading model from path /tmp/tmp1avgwb8w/model/ with prefix 9846bb0b465f4312
# [INFO 26-08-10 17:14:32.0627 UTC quick_scorer_extended.cc:911] The binary was compiled without AVX2 support, but your CPU supports it. Enable it for faster model inference.
# [INFO 26-08-10 17:14:32.0633 UTC abstract_model.cc:1362] Engine "GradientBoostedTreesQuickScorerExtended" built
# [INFO 26-08-10 17:14:32.0633 UTC kernel.cc:1061] Use fast generic engine
# Model compiled.
# CPU times: user 6.7 s, sys: 1.48 s, total: 8.18 s
# Wall time: 6.66 s

# %%
# Evaluate the model
evaluate = model.evaluate(val_ds, return_dict=True)
print()

for name, value in evaluate.items():
    print(f"{name}: {value:.4f}")
# Out:
# WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 1/1 [==============================] - ETA: 0s - loss: 0.0000e+00 - accuracy: 1.0000
# 1/1 [==============================] - 3s 3s/step - loss: 0.0000e+00 - accuracy: 1.0000
# loss: 0.0000
# accuracy: 1.0000

# %%
# Model Summary
model.summary()
# Out:
# Model: "gradient_boosted_trees_model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
# =================================================================
# Total params: 1 (1.00 Byte)
# Trainable params: 0 (0.00 Byte)
# Non-trainable params: 1 (1.00 Byte)
# _________________________________________________________________
# Type: "GRADIENT_BOOSTED_TREES"
# Task: CLASSIFICATION
# Label: "__LABEL"
#
# Input Features (18):
# 	10Percentile
# 	90Percentile
# 	Energy
# 	Entropy
# 	InterquartileRange
# 	Kurtosis
# 	Maximum
# 	Mean
# 	MeanAbsoluteDeviation
# 	Median
# 	Minimum
# 	Range
# 	RobustMeanAbsoluteDeviation
# 	RootMeanSquared
# 	Skewness
# 	TotalEnergy
# 	Uniformity
# 	Variance
#
# Trained with weights
#
# Variable Importance: INV_MEAN_MIN_DEPTH:
#     1.             "RootMeanSquared"  0.461619 ################
#     2.                      "Energy"  0.296542 #####
#     3.                 "TotalEnergy"  0.282149 #####
#     4.                        "Mean"  0.238977 ##
#     5.                      "Median"  0.227642 #
#     6.                     "Minimum"  0.224697 #
#     7.                "10Percentile"  0.212419
#     8.                "90Percentile"  0.208835
#     9.                     "Maximum"  0.208348
#    10.                     "Entropy"  0.200616
#    11.                    "Kurtosis"  0.200413
#    12.          "InterquartileRange"  0.200406
#    13.                    "Skewness"  0.200041
#    14.                       "Range"  0.200013
#    15.       "MeanAbsoluteDeviation"  0.199058
#    16.                  "Uniformity"  0.198497
#    17. "RobustMeanAbsoluteDeviation"  0.198420
#    18.                    "Variance"  0.198244
#
# Variable Importance: NUM_AS_ROOT:
#     1. "RootMeanSquared" 204.000000 ################
#     2.            "Mean" 52.000000 ####
#     3.          "Median" 30.000000 ##
#     4.         "Minimum" 12.000000
#     5.          "Energy"  1.000000
#     6.     "TotalEnergy"  1.000000
#
# Variable Importance: NUM_NODES:
#     1.             "RootMeanSquared" 536.000000 ################
#     2.                     "Minimum" 471.000000 #############
#     3.                      "Energy" 423.000000 ############
#     4.                 "TotalEnergy" 399.000000 ###########
#     5.                "90Percentile" 305.000000 ########
#     6.                "10Percentile" 302.000000 ########
#     7.                      "Median" 281.000000 #######
#     8.                     "Maximum" 227.000000 ######
#     9.                        "Mean" 219.000000 #####
#    10.                    "Kurtosis" 112.000000 ##
#    11.          "InterquartileRange" 106.000000 ##
#    12.                    "Skewness" 82.000000 #
#    13.                     "Entropy" 75.000000 #
#    14.       "MeanAbsoluteDeviation" 75.000000 #
#    15.                       "Range" 73.000000 #
#    16. "RobustMeanAbsoluteDeviation" 40.000000
#    17.                  "Uniformity" 36.000000
#    18.                    "Variance" 34.000000
#
# Variable Importance: SUM_SCORE:
#     1.                      "Median" 653.696378 ################
#     2.                      "Energy" 176.122363 ####
#     3.                 "TotalEnergy" 56.008298 #
#     4.             "RootMeanSquared" 51.299697 #
#     5.                  "Uniformity"  3.683752
#     6.                     "Entropy"  3.087116
#     7.                     "Minimum"  1.875289
#     8.                    "Kurtosis"  1.660094
#     9.                "90Percentile"  1.624104
#    10.                     "Maximum"  1.082779
#    11.                        "Mean"  0.687313
#    12.                "10Percentile"  0.543464
#    13.                       "Range"  0.385832
#    14.          "InterquartileRange"  0.090317
#    15.                    "Skewness"  0.050048
#    16.       "MeanAbsoluteDeviation"  0.031630
#    17. "RobustMeanAbsoluteDeviation"  0.017606
#    18.                    "Variance"  0.004503
#
#
#
# Loss: BINOMIAL_LOG_LIKELIHOOD
# Validation loss value: 1.12825e-05
# Number of trees per iteration: 1
# Node format: NOT_SET
# Number of trees: 300
# Total number of nodes: 7892
#
# Number of nodes by tree:
# Count: 300 Average: 26.3067 StdDev: 4.27699
# Min: 21 Max: 41 Ignored: 0
# ----------------------------------------------
# [ 21, 22)   1   0.33%   0.33%
# [ 22, 23)   0   0.00%   0.33%
# [ 23, 24) 175  58.33%  58.67% ##########
# [ 24, 25)   0   0.00%  58.67%
# [ 25, 26)   6   2.00%  60.67%
# [ 26, 27)   0   0.00%  60.67%
# [ 27, 28)   8   2.67%  63.33%
# [ 28, 29)   0   0.00%  63.33%
# [ 29, 30)  13   4.33%  67.67% #
# [ 30, 31)   0   0.00%  67.67%
# [ 31, 32)  63  21.00%  88.67% ####
# [ 32, 33)   0   0.00%  88.67%
# [ 33, 34)  26   8.67%  97.33% #
# [ 34, 35)   0   0.00%  97.33%
# [ 35, 36)   6   2.00%  99.33%
# [ 36, 37)   0   0.00%  99.33%
# [ 37, 38)   0   0.00%  99.33%
# [ 38, 39)   0   0.00%  99.33%
# [ 39, 40)   0   0.00%  99.33%
# [ 40, 41]   2   0.67% 100.00%
#
# Depth by leafs:
# Count: 4096 Average: 4.10596 StdDev: 0.932017
# Min: 2 Max: 5 Ignored: 0
# ----------------------------------------------
# [ 2, 3)  257   6.27%   6.27% #
# [ 3, 4)  814  19.87%  26.15% #####
# [ 4, 5) 1263  30.83%  56.98% #######
# [ 5, 5] 1762  43.02% 100.00% ##########
#
# Number of training obs by leaf:
# Count: 4096 Average: 51.9287 StdDev: 107.929
# Min: 5 Max: 336 Ignored: 0
# ----------------------------------------------
# [   5,  21) 3439  83.96%  83.96% ##########
# [  21,  38)   43   1.05%  85.01%
# [  38,  54)   12   0.29%  85.30%
# [  54,  71)    1   0.02%  85.33%
# [  71,  88)    1   0.02%  85.35%
# [  88, 104)    0   0.00%  85.35%
# [ 104, 121)    0   0.00%  85.35%
# [ 121, 137)    0   0.00%  85.35%
# [ 137, 154)    0   0.00%  85.35%
# [ 154, 171)    0   0.00%  85.35%
# [ 171, 187)    0   0.00%  85.35%
# [ 187, 204)    0   0.00%  85.35%
# [ 204, 220)    0   0.00%  85.35%
# [ 220, 237)    3   0.07%  85.42%
# [ 237, 254)    3   0.07%  85.50%
# [ 254, 270)    5   0.12%  85.62%
# [ 270, 287)   22   0.54%  86.16%
# [ 287, 303)   50   1.22%  87.38%
# [ 303, 320)  323   7.89%  95.26% #
# [ 320, 336]  194   4.74% 100.00% #
#
# Attribute in nodes:
# 	536 : RootMeanSquared [NUMERICAL]
# 	471 : Minimum [NUMERICAL]
# 	423 : Energy [NUMERICAL]
# 	399 : TotalEnergy [NUMERICAL]
# 	305 : 90Percentile [NUMERICAL]
# 	302 : 10Percentile [NUMERICAL]
# 	281 : Median [NUMERICAL]
# 	227 : Maximum [NUMERICAL]
# 	219 : Mean [NUMERICAL]
# 	112 : Kurtosis [NUMERICAL]
# 	106 : InterquartileRange [NUMERICAL]
# 	82 : Skewness [NUMERICAL]
# 	75 : MeanAbsoluteDeviation [NUMERICAL]
# 	75 : Entropy [NUMERICAL]
# 	73 : Range [NUMERICAL]
# 	40 : RobustMeanAbsoluteDeviation [NUMERICAL]
# 	36 : Uniformity [NUMERICAL]
# 	34 : Variance [NUMERICAL]
#
# Attribute in nodes with depth <= 0:
# 	204 : RootMeanSquared [NUMERICAL]
# 	52 : Mean [NUMERICAL]
# 	30 : Median [NUMERICAL]
# 	12 : Minimum [NUMERICAL]
# 	1 : TotalEnergy [NUMERICAL]
# 	1 : Energy [NUMERICAL]
#
# Attribute in nodes with depth <= 1:
# 	248 : RootMeanSquared [NUMERICAL]
# 	203 : Energy [NUMERICAL]
# 	169 : TotalEnergy [NUMERICAL]
# 	121 : Mean [NUMERICAL]
# 	52 : Entropy [NUMERICAL]
# 	30 : Median [NUMERICAL]
# 	19 : Range [NUMERICAL]
# 	18 : 90Percentile [NUMERICAL]
# 	14 : Variance [NUMERICAL]
# 	13 : Maximum [NUMERICAL]
# 	12 : Minimum [NUMERICAL]
# 	1 : 10Percentile [NUMERICAL]
#
# Attribute in nodes with depth <= 2:
# 	361 : Energy [NUMERICAL]
# 	343 : TotalEnergy [NUMERICAL]
# 	301 : RootMeanSquared [NUMERICAL]
# 	169 : Mean [NUMERICAL]
# 	155 : Median [NUMERICAL]
# 	95 : 10Percentile [NUMERICAL]
# 	82 : 90Percentile [NUMERICAL]
# 	71 : Entropy [NUMERICAL]
# 	64 : Maximum [NUMERICAL]
# 	63 : Kurtosis [NUMERICAL]
# 	35 : Range [NUMERICAL]
# 	30 : Minimum [NUMERICAL]
# 	28 : Uniformity [NUMERICAL]
# 	16 : Variance [NUMERICAL]
# 	9 : InterquartileRange [NUMERICAL]
# 	8 : RobustMeanAbsoluteDeviation [NUMERICAL]
# 	7 : MeanAbsoluteDeviation [NUMERICAL]
# 	6 : Skewness [NUMERICAL]
#
# Attribute in nodes with depth <= 3:
# 	417 : Minimum [NUMERICAL]
# 	400 : Energy [NUMERICAL]
# 	387 : TotalEnergy [NUMERICAL]
# 	337 : RootMeanSquared [NUMERICAL]
# 	224 : 90Percentile [NUMERICAL]
# 	204 : Mean [NUMERICAL]
# 	194 : Median [NUMERICAL]
# 	171 : Maximum [NUMERICAL]
# 	149 : 10Percentile [NUMERICAL]
# 	106 : Kurtosis [NUMERICAL]
# 	72 : Entropy [NUMERICAL]
# 	66 : Skewness [NUMERICAL]
# 	51 : Range [NUMERICAL]
# 	40 : InterquartileRange [NUMERICAL]
# 	31 : Uniformity [NUMERICAL]
# 	24 : RobustMeanAbsoluteDeviation [NUMERICAL]
# 	23 : MeanAbsoluteDeviation [NUMERICAL]
# 	19 : Variance [NUMERICAL]
#
# Attribute in nodes with depth <= 5:
# 	536 : RootMeanSquared [NUMERICAL]
# 	471 : Minimum [NUMERICAL]
# 	423 : Energy [NUMERICAL]
# 	399 : TotalEnergy [NUMERICAL]
# 	305 : 90Percentile [NUMERICAL]
# 	302 : 10Percentile [NUMERICAL]
# 	281 : Median [NUMERICAL]
# 	227 : Maximum [NUMERICAL]
# 	219 : Mean [NUMERICAL]
# 	112 : Kurtosis [NUMERICAL]
# 	106 : InterquartileRange [NUMERICAL]
# 	82 : Skewness [NUMERICAL]
# 	75 : MeanAbsoluteDeviation [NUMERICAL]
# 	75 : Entropy [NUMERICAL]
# 	73 : Range [NUMERICAL]
# 	40 : RobustMeanAbsoluteDeviation [NUMERICAL]
# 	36 : Uniformity [NUMERICAL]
# 	34 : Variance [NUMERICAL]
#
# Condition type in nodes:
# 	3796 : HigherCondition
# Condition type in nodes with depth <= 0:
# 	300 : HigherCondition
# Condition type in nodes with depth <= 1:
# 	900 : HigherCondition
# Condition type in nodes with depth <= 2:
# 	1843 : HigherCondition
# Condition type in nodes with depth <= 3:
# 	2915 : HigherCondition
# Condition type in nodes with depth <= 5:
# 	3796 : HigherCondition
#
# Training logs:
# Number of iteration to final model: 300
# 	Iter:1 train-loss:1.197614 valid-loss:1.208818  train-accuracy:0.997178 valid-accuracy:0.985659
# 	Iter:2 train-loss:1.043176 valid-loss:1.052368  train-accuracy:1.000000 valid-accuracy:0.985659
# 	Iter:3 train-loss:0.914288 valid-loss:0.921995  train-accuracy:0.998634 valid-accuracy:0.985659
# 	Iter:4 train-loss:0.805196 valid-loss:0.814579  train-accuracy:1.000000 valid-accuracy:1.000000
# 	Iter:5 train-loss:0.712026 valid-loss:0.726511  train-accuracy:1.000000 valid-accuracy:0.985659
# 	Iter:6 train-loss:0.631648 valid-loss:0.645136  train-accuracy:1.000000 valid-accuracy:1.000000
# 	Iter:16 train-loss:0.210981 valid-loss:0.226124  train-accuracy:1.000000 valid-accuracy:1.000000
# 	Iter:26 train-loss:0.075950 valid-loss:0.097599  train-accuracy:1.000000 valid-accuracy:0.985659
# 	Iter:36 train-loss:0.028228 valid-loss:0.050864  train-accuracy:1.000000 valid-accuracy:0.985659
# 	Iter:46 train-loss:0.010323 valid-loss:0.020223  train-accuracy:1.000000 valid-accuracy:1.000000
# 	Iter:56 train-loss:0.003789 valid-loss:0.007745  train-accuracy:1.000000 valid-accuracy:1.000000
# 	Iter:66 train-loss:0.001393 valid-loss:0.002899  train-accuracy:1.000000 valid-accuracy:1.000000
# 	Iter:76 train-loss:0.000513 valid-loss:0.001074  train-accuracy:1.000000 valid-accuracy:1.000000
# 	Iter:86 train-loss:0.000190 valid-loss:0.000398  train-accuracy:1.000000 valid-accuracy:1.000000
# 	Iter:96 train-loss:0.000075 valid-loss:0.000158  train-accuracy:1.000000 valid-accuracy:1.000000
# 	Iter:106 train-loss:0.000033 valid-loss:0.000083  train-accuracy:1.000000 valid-accuracy:1.000000
# 	Iter:116 train-loss:0.000017 valid-loss:0.000064  train-accuracy:1.000000 valid-accuracy:1.000000
# 	Iter:126 train-loss:0.000010 valid-loss:0.000047  train-accuracy:1.000000 valid-accuracy:1.000000
# 	Iter:136 train-loss:0.000007 valid-loss:0.000039  train-accuracy:1.000000 valid-accuracy:1.000000
# 	Iter:146 train-loss:0.000005 valid-loss:0.000034  train-accuracy:1.000000 valid-accuracy:1.000000
# 	Iter:156 train-loss:0.000004 valid-loss:0.000029  train-accuracy:1.000000 valid-accuracy:1.000000
# 	Iter:166 train-loss:0.000004 valid-loss:0.000026  train-accuracy:1.000000 valid-accuracy:1.000000
# 	Iter:176 train-loss:0.000003 valid-loss:0.000024  train-accuracy:1.000000 valid-accuracy:1.000000
# 	Iter:186 train-loss:0.000003 valid-loss:0.000022  train-accuracy:1.000000 valid-accuracy:1.000000
# 	Iter:196 train-loss:0.000003 valid-loss:0.000020  train-accuracy:1.000000 valid-accuracy:1.000000
# 	Iter:206 train-loss:0.000002 valid-loss:0.000019  train-accuracy:1.000000 valid-accuracy:1.000000
# 	Iter:216 train-loss:0.000002 valid-loss:0.000017  train-accuracy:1.000000 valid-accuracy:1.000000
# 	Iter:226 train-loss:0.000002 valid-loss:0.000016  train-accuracy:1.000000 valid-accuracy:1.000000
# 	Iter:236 train-loss:0.000002 valid-loss:0.000015  train-accuracy:1.000000 valid-accuracy:1.000000
# 	Iter:246 train-loss:0.000002 valid-loss:0.000015  train-accuracy:1.000000 valid-accuracy:1.000000
# 	Iter:256 train-loss:0.000002 valid-loss:0.000014  train-accuracy:1.000000 valid-accuracy:1.000000
# 	Iter:266 train-loss:0.000002 valid-loss:0.000013  train-accuracy:1.000000 valid-accuracy:1.000000
# 	Iter:276 train-loss:0.000002 valid-loss:0.000013  train-accuracy:1.000000 valid-accuracy:1.000000
# 	Iter:286 train-loss:0.000001 valid-loss:0.000012  train-accuracy:1.000000 valid-accuracy:1.000000
# 	Iter:296 train-loss:0.000001 valid-loss:0.000011  train-accuracy:1.000000 valid-accuracy:1.000000

# %%
# Model features
model.make_inspector().features()
# Out:
# ["10Percentile" (1; #0),
#  "90Percentile" (1; #1),
#  "Energy" (1; #2),
#  "Entropy" (1; #3),
#  "InterquartileRange" (1; #4),
#  "Kurtosis" (1; #5),
#  "Maximum" (1; #6),
#  "Mean" (1; #7),
#  "MeanAbsoluteDeviation" (1; #8),
#  "Median" (1; #9),
#  "Minimum" (1; #10),
#  "Range" (1; #11),
#  "RobustMeanAbsoluteDeviation" (1; #12),
#  "RootMeanSquared" (1; #13),
#  "Skewness" (1; #14),
#  "TotalEnergy" (1; #15),
#  "Uniformity" (1; #16),
#  "Variance" (1; #17)]

# %%
# Feature importance
model.make_inspector().variable_importances()
# Out:
# {'INV_MEAN_MIN_DEPTH': [("RootMeanSquared" (1; #13), 0.4616189355994147),
#   ("Energy" (1; #2), 0.2965422651133747),
#   ("TotalEnergy" (1; #15), 0.2821488060518536),
#   ("Mean" (1; #7), 0.23897730496132358),
#   ("Median" (1; #9), 0.22764183785132822),
#   ("Minimum" (1; #10), 0.22469738557687877),
#   ("10Percentile" (1; #0), 0.2124190421221791),
#   ("90Percentile" (1; #1), 0.20883542884684844),
#   ("Maximum" (1; #6), 0.20834822734275701),
#   ("Entropy" (1; #3), 0.20061583472114403),
#   ("Kurtosis" (1; #5), 0.2004129806210249),
#   ("InterquartileRange" (1; #4), 0.20040619053974207),
#   ("Skewness" (1; #14), 0.20004069974605995),
#   ("Range" (1; #11), 0.20001274822851842),
#   ("MeanAbsoluteDeviation" (1; #8), 0.19905767742094713),
#   ("Uniformity" (1; #16), 0.19849693311580402),
#   ("RobustMeanAbsoluteDeviation" (1; #12), 0.19842004993355974),
#   ("Variance" (1; #17), 0.1982443894446543)],
#  'SUM_SCORE': [("Median" (1; #9), 653.6963783510234),
#   ("Energy" (1; #2), 176.12236263724844),
#   ("TotalEnergy" (1; #15), 56.008298222344074),
#   ("RootMeanSquared" (1; #13), 51.29969713689073),
#   ("Uniformity" (1; #16), 3.683752228980776),
#   ("Entropy" (1; #3), 3.0871158697498147),
#   ("Minimum" (1; #10), 1.8752892079413912),
#   ("Kurtosis" (1; #5), 1.6600940994602584),
#   ("90Percentile" (1; #1), 1.6241040000818927),
#   ("Maximum" (1; #6), 1.0827792495282262),
#   ("Mean" (1; #7), 0.6873130184701357),
#   ("10Percentile" (1; #0), 0.5434643422373476),
#   ("Range" (1; #11), 0.3858324253390555),
#   ("InterquartileRange" (1; #4), 0.09031703229130703),
#   ("Skewness" (1; #14), 0.05004837482661284),
#   ("MeanAbsoluteDeviation" (1; #8), 0.03162995231474727),
#   ("RobustMeanAbsoluteDeviation" (1; #12), 0.01760585717279452),
#   ("Variance" (1; #17), 0.004503384863013681)],
#  'NUM_AS_ROOT': [("RootMeanSquared" (1; #13), 204.0),
#   ("Mean" (1; #7), 52.0),
#   ("Median" (1; #9), 30.0),
#   ("Minimum" (1; #10), 12.0),
#   ("Energy" (1; #2), 1.0),
#   ("TotalEnergy" (1; #15), 1.0)],
#  'NUM_NODES': [("RootMeanSquared" (1; #13), 536.0),
#   ("Minimum" (1; #10), 471.0),
#   ("Energy" (1; #2), 423.0),
#   ("TotalEnergy" (1; #15), 399.0),
#   ("90Percentile" (1; #1), 305.0),
#   ("10Percentile" (1; #0), 302.0),
#   ("Median" (1; #9), 281.0),
#   ("Maximum" (1; #6), 227.0),
#   ("Mean" (1; #7), 219.0),
#   ("Kurtosis" (1; #5), 112.0),
#   ("InterquartileRange" (1; #4), 106.0),
#   ("Skewness" (1; #14), 82.0),
#   ("Entropy" (1; #3), 75.0),
#   ("MeanAbsoluteDeviation" (1; #8), 75.0),
#   ("Range" (1; #11), 73.0),
#   ("RobustMeanAbsoluteDeviation" (1; #12), 40.0),
#   ("Uniformity" (1; #16), 36.0),
#   ("Variance" (1; #17), 34.0)]}

# %%
# Model self evaluation
model.make_inspector().evaluation()
# Out:
# Evaluation(num_examples=None, accuracy=1.0, loss=1.128252552007325e-05, rmse=None, ndcg=None, aucs=None, auuc=None, qini=None)

# %%
logs = model.make_inspector().training_logs()

plt.figure(figsize=(12, 4))
plt.subplot(1, 2, 1)
plt.plot([log.num_trees for log in logs], [log.evaluation.accuracy for log in logs])
plt.xlabel("Number of trees")
plt.ylabel("Accuracy (out-of-bag)")
plt.subplot(1, 2, 2)
plt.plot([log.num_trees for log in logs], [log.evaluation.loss for log in logs])
plt.xlabel("Number of trees")
plt.ylabel("Logloss (out-of-bag)")
plt.show()

# %% [markdown]
# Calculate the score of our hold-out validation dataset

# %%
predictions = model.predict(val_ds)
y_true      = validation_data["label"]

from sklearn.metrics import roc_auc_score
ROC_AUC = roc_auc_score(y_true, predictions)
print("The ROC AUC score is %.5f" % ROC_AUC )
# Out:
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 58ms/step
# The ROC AUC score is 1.00000

# %%
# Compute binary classification metrics with sklearn
import numpy as np
from sklearn.metrics import (
    accuracy_score,
    precision_score,
    recall_score,
    f1_score,
    roc_auc_score,
    average_precision_score,
    confusion_matrix,
    classification_report,
    matthews_corrcoef,
    log_loss,
    brier_score_loss,
)

# Get predictions (probabilities or class labels)
preds = model.predict(test_ds)
# If model outputs probabilities, convert to labels by threshold 0.5
if preds.ndim == 2:
    # For TFDF classification, preds may be class probabilities with shape (N, 2)
    if preds.shape[1] == 2:
        pos_probs = preds[:, 1]
    else:
        # If single-probability column (positive class)
        pos_probs = preds[:, -1]
    y_pred = (pos_probs >= 0.5).astype(int)
else:
    # Already class labels
    y_pred = preds.astype(int)
    pos_probs = None

# Ground truth labels (must be 0/1 integers)
y_true = test_data["label"].astype(int).to_numpy()

# Core metrics
metrics = {}
metrics["accuracy"] = accuracy_score(y_true, y_pred)
metrics["precision"] = precision_score(y_true, y_pred, zero_division=0)
metrics["recall"] = recall_score(y_true, y_pred, zero_division=0)
metrics["f1"] = f1_score(y_true, y_pred, zero_division=0)
metrics["mcc"] = matthews_corrcoef(y_true, y_pred)

# Probabilistic metrics (only if we have probabilities)
if pos_probs is not None:
    metrics["roc_auc"] = roc_auc_score(y_true, pos_probs)
    metrics["pr_auc"] = average_precision_score(y_true, pos_probs)
    metrics["log_loss"] = log_loss(y_true, pos_probs, labels=[0,1])
    metrics["brier_score"] = brier_score_loss(y_true, pos_probs)

# Confusion matrix and detailed report
cm = confusion_matrix(y_true, y_pred, labels=[0,1])
report = classification_report(y_true, y_pred, digits=4)

print("Sklearn binary metrics:")
for k, v in metrics.items():
    print(f"{k}: {v:.4f}")
print("\nConfusion matrix:\n", cm)
print("\nClassification report:\n", report)
# Out:
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 61ms/step
# Sklearn binary metrics:
# accuracy: 1.0000
# precision: 1.0000
# recall: 1.0000
# f1: 1.0000
# mcc: 1.0000
# roc_auc: 1.0000
# pr_auc: 1.0000
# log_loss: 0.0013
# brier_score: 0.0003
#
# Confusion matrix:
#  [[104   0]
#  [  0 118]]
#
# Classification report:
#                precision    recall  f1-score   support
#
#            0     1.0000    1.0000    1.0000       104
#            1     1.0000    1.0000    1.0000       118
#
#     accuracy                         1.0000       222
#    macro avg     1.0000    1.0000    1.0000       222
# weighted avg     1.0000    1.0000    1.0000       222
