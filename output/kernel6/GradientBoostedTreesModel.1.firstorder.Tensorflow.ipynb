# %%
# Import packages and modules
import numpy  as np
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow_decision_forests as tfdf

from sklearn.model_selection import train_test_split
# Out:
# 2026-08-12 05:39:19.124427: I tensorflow/core/util/port.cc:113] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2026-08-12 05:39:19.475611: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2026-08-12 05:39:23.927763: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
# Check the version of TensorFlow Decision Forests
print("Found TensorFlow Decision Forests v" + tfdf.__version__)
# Out:
# Found TensorFlow Decision Forests v1.9.1

# %%
datasetPath = 'dataset/firstorder/kernel5-radius5/dataset.csv'

# %%
# Parameters
datasetPath = "dataset/firstorder/kernel6-radius6/1.dataset.csv"

# %%
# train/validation/test = 70/10/20
dataset = pd.read_csv(datasetPath)

train_data, temp_data = train_test_split(dataset, test_size=0.3, random_state=42)
validation_data, test_data = train_test_split(temp_data, test_size=2/3, random_state=42)

# %%
from sklearn.utils.class_weight import compute_class_weight

# tinh class weight tren tap train
classes = np.array([0, 1])
weights = compute_class_weight(class_weight="balanced", classes=classes, y=train_data["label"])
class_weight = {0: weights[0], 1: weights[1]}

# gan sample_weight cho tung dong
train_data["sample_weight"] = train_data["label"].map(class_weight)
validation_data["sample_weight"] = validation_data["label"].map(class_weight)
test_data["sample_weight"] = test_data["label"].map(class_weight)

# Convert the dataset into a TensorFlow dataset.
train_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    train_data, label="label", weight="sample_weight"
)         
val_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    validation_data, label="label", weight="sample_weight"
)
test_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    test_data, label="label", weight="sample_weight"
)
# Out:
# 2026-08-12 05:39:36.113770: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:984] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2026-08-12 05:39:36.115187: W tensorflow/core/common_runtime/gpu/gpu_device.cc:2251] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...

# %%
import keras

# %%
# %%time

# Train a Gradient Boosted Trees model.
model = tfdf.keras.GradientBoostedTreesModel()

# Add evaluation metrics
model.compile(
    metrics=["accuracy"]
)
model.fit(x=train_ds)

# # Train a Gradient Boosted Trees model.
# model = tfdf.keras.GradientBoostedTreesModel(num_trees=1500)
# model.fit(train_ds)
# Out:
# Use /tmp/tmp2om4j8ym as temporary training directory
# Reading training dataset...
# [WARNING 26-08-12 05:39:36.2774 UTC gradient_boosted_trees.cc:1840] "goss_alpha" set but "sampling_method" not equal to "GOSS".
# [WARNING 26-08-12 05:39:36.2777 UTC gradient_boosted_trees.cc:1851] "goss_beta" set but "sampling_method" not equal to "GOSS".
# [WARNING 26-08-12 05:39:36.2777 UTC gradient_boosted_trees.cc:1865] "selective_gradient_boosting_ratio" set but "sampling_method" not equal to "SELGB".
# Training dataset read in 0:00:02.408227. Found 450 examples.
# Training model...
# Model trained in 0:00:00.447644
# Compiling model...
# [INFO 26-08-12 05:39:39.1607 UTC kernel.cc:1233] Loading model from path /tmp/tmp2om4j8ym/model/ with prefix 43a8d68675e945f0
# [INFO 26-08-12 05:39:39.1643 UTC quick_scorer_extended.cc:911] The binary was compiled without AVX2 support, but your CPU supports it. Enable it for faster model inference.
# [INFO 26-08-12 05:39:39.1645 UTC abstract_model.cc:1362] Engine "GradientBoostedTreesQuickScorerExtended" built
# [INFO 26-08-12 05:39:39.1645 UTC kernel.cc:1061] Use fast generic engine
# Model compiled.
# CPU times: user 5.62 s, sys: 665 ms, total: 6.29 s
# Wall time: 5.75 s

# %%
# Evaluate the model
evaluate = model.evaluate(val_ds, return_dict=True)
print()

for name, value in evaluate.items():
    print(f"{name}: {value:.4f}")
# Out:
# WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 1/1 [==============================] - ETA: 0s - loss: 0.0000e+00 - accuracy: 1.0000
# 1/1 [==============================] - 3s 3s/step - loss: 0.0000e+00 - accuracy: 1.0000
# loss: 0.0000
# accuracy: 1.0000

# %%
# Model Summary
model.summary()
# Out:
# Model: "gradient_boosted_trees_model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
# =================================================================
# Total params: 1 (1.00 Byte)
# Trainable params: 0 (0.00 Byte)
# Non-trainable params: 1 (1.00 Byte)
# _________________________________________________________________
# Type: "GRADIENT_BOOSTED_TREES"
# Task: CLASSIFICATION
# Label: "__LABEL"
#
# Input Features (18):
# 	10Percentile
# 	90Percentile
# 	Energy
# 	Entropy
# 	InterquartileRange
# 	Kurtosis
# 	Maximum
# 	Mean
# 	MeanAbsoluteDeviation
# 	Median
# 	Minimum
# 	Range
# 	RobustMeanAbsoluteDeviation
# 	RootMeanSquared
# 	Skewness
# 	TotalEnergy
# 	Uniformity
# 	Variance
#
# Trained with weights
#
# Variable Importance: INV_MEAN_MIN_DEPTH:
#     1.                      "Median"  0.300502 ################
#     2.                     "Minimum"  0.239663 #######
#     3.                "10Percentile"  0.229548 #####
#     4.                     "Entropy"  0.227434 #####
#     5.                "90Percentile"  0.215329 ###
#     6.                     "Maximum"  0.212820 ###
#     7.             "RootMeanSquared"  0.209468 ##
#     8.                       "Range"  0.209157 ##
#     9.                    "Skewness"  0.208956 ##
#    10.                      "Energy"  0.206866 ##
#    11.                 "TotalEnergy"  0.203836 #
#    12.                  "Uniformity"  0.203396 #
#    13.                    "Kurtosis"  0.202227 #
#    14.                        "Mean"  0.199050 #
#    15. "RobustMeanAbsoluteDeviation"  0.196851
#    16.       "MeanAbsoluteDeviation"  0.196552
#    17.                    "Variance"  0.192943
#    18.          "InterquartileRange"  0.191844
#
# Variable Importance: NUM_AS_ROOT:
#     1.          "Median" 33.000000 ################
#     2.    "10Percentile" 12.000000 #####
#     3. "RootMeanSquared"  8.000000 ###
#     4.          "Energy"  7.000000 ###
#     5.         "Maximum"  6.000000 ##
#     6.         "Minimum"  5.000000 ##
#     7.     "TotalEnergy"  5.000000 ##
#     8.    "90Percentile"  4.000000 #
#     9.           "Range"  4.000000 #
#    10.        "Skewness"  2.000000
#    11.         "Entropy"  1.000000
#    12.        "Kurtosis"  1.000000
#
# Variable Importance: NUM_NODES:
#     1.                      "Median" 148.000000 ################
#     2.                     "Minimum" 144.000000 ###############
#     3.                     "Entropy" 139.000000 ##############
#     4.                    "Skewness" 107.000000 ##########
#     5.                "90Percentile" 106.000000 ##########
#     6.                       "Range" 92.000000 #########
#     7.                "10Percentile" 89.000000 ########
#     8.                     "Maximum" 80.000000 #######
#     9.                    "Kurtosis" 74.000000 ######
#    10.                        "Mean" 66.000000 #####
#    11.                  "Uniformity" 61.000000 #####
#    12.             "RootMeanSquared" 40.000000 ##
#    13.                      "Energy" 39.000000 ##
#    14. "RobustMeanAbsoluteDeviation" 38.000000 ##
#    15.                 "TotalEnergy" 38.000000 ##
#    16.                    "Variance" 29.000000 #
#    17.       "MeanAbsoluteDeviation" 25.000000
#    18.          "InterquartileRange" 17.000000
#
# Variable Importance: SUM_SCORE:
#     1.                      "Energy" 189.204369 ################
#     2.             "RootMeanSquared" 98.274191 ########
#     3.                      "Median" 69.078883 #####
#     4.                "90Percentile" 30.777629 ##
#     5.                    "Skewness" 25.996762 ##
#     6.                     "Entropy" 24.517570 #
#     7.                     "Minimum" 23.997963 #
#     8.                "10Percentile" 15.118284 #
#     9.                    "Kurtosis" 13.882535 #
#    10.                  "Uniformity" 11.356845
#    11.       "MeanAbsoluteDeviation"  8.579888
#    12.                       "Range"  8.055330
#    13.                     "Maximum"  6.361433
#    14.                        "Mean"  3.829758
#    15.                    "Variance"  3.631162
#    16.                 "TotalEnergy"  3.179704
#    17. "RobustMeanAbsoluteDeviation"  2.967234
#    18.          "InterquartileRange"  2.107553
#
#
#
# Loss: BINOMIAL_LOG_LIKELIHOOD
# Validation loss value: 0.0451582
# Number of trees per iteration: 1
# Node format: NOT_SET
# Number of trees: 88
# Total number of nodes: 2752
#
# Number of nodes by tree:
# Count: 88 Average: 31.2727 StdDev: 6.09904
# Min: 19 Max: 43 Ignored: 0
# ----------------------------------------------
# [ 19, 20)  2   2.27%   2.27% ##
# [ 20, 21)  0   0.00%   2.27%
# [ 21, 22)  6   6.82%   9.09% #####
# [ 22, 24)  5   5.68%  14.77% ####
# [ 24, 25)  0   0.00%  14.77%
# [ 25, 26)  4   4.55%  19.32% ###
# [ 26, 27)  0   0.00%  19.32%
# [ 27, 29) 13  14.77%  34.09% ##########
# [ 29, 30)  6   6.82%  40.91% #####
# [ 30, 31)  0   0.00%  40.91%
# [ 31, 32) 11  12.50%  53.41% ########
# [ 32, 34)  8   9.09%  62.50% ######
# [ 34, 35)  0   0.00%  62.50%
# [ 35, 36) 10  11.36%  73.86% ########
# [ 36, 37)  0   0.00%  73.86%
# [ 37, 39) 11  12.50%  86.36% ########
# [ 39, 40)  5   5.68%  92.05% ####
# [ 40, 41)  0   0.00%  92.05%
# [ 41, 42)  5   5.68%  97.73% ####
# [ 42, 43]  2   2.27% 100.00% ##
#
# Depth by leafs:
# Count: 1420 Average: 4.33803 StdDev: 0.882437
# Min: 2 Max: 5 Ignored: 0
# ----------------------------------------------
# [ 2, 3)  62   4.37%   4.37% #
# [ 3, 4) 208  14.65%  19.01% ###
# [ 4, 5) 338  23.80%  42.82% ####
# [ 5, 5] 812  57.18% 100.00% ##########
#
# Number of training obs by leaf:
# Count: 1420 Average: 25.2225 StdDev: 54.2981
# Min: 5 Max: 341 Ignored: 0
# ----------------------------------------------
# [   5,  21) 1162  81.83%  81.83% ##########
# [  21,  38)   89   6.27%  88.10% #
# [  38,  55)   20   1.41%  89.51%
# [  55,  72)   20   1.41%  90.92%
# [  72,  89)   14   0.99%  91.90%
# [  89, 106)   14   0.99%  92.89%
# [ 106, 122)    8   0.56%  93.45%
# [ 122, 139)    8   0.56%  94.01%
# [ 139, 156)   13   0.92%  94.93%
# [ 156, 173)    8   0.56%  95.49%
# [ 173, 190)    5   0.35%  95.85%
# [ 190, 207)   11   0.77%  96.62%
# [ 207, 224)    7   0.49%  97.11%
# [ 224, 240)    7   0.49%  97.61%
# [ 240, 257)   13   0.92%  98.52%
# [ 257, 274)    4   0.28%  98.80%
# [ 274, 291)   10   0.70%  99.51%
# [ 291, 308)    2   0.14%  99.65%
# [ 308, 325)    3   0.21%  99.86%
# [ 325, 341]    2   0.14% 100.00%
#
# Attribute in nodes:
# 	148 : Median [NUMERICAL]
# 	144 : Minimum [NUMERICAL]
# 	139 : Entropy [NUMERICAL]
# 	107 : Skewness [NUMERICAL]
# 	106 : 90Percentile [NUMERICAL]
# 	92 : Range [NUMERICAL]
# 	89 : 10Percentile [NUMERICAL]
# 	80 : Maximum [NUMERICAL]
# 	74 : Kurtosis [NUMERICAL]
# 	66 : Mean [NUMERICAL]
# 	61 : Uniformity [NUMERICAL]
# 	40 : RootMeanSquared [NUMERICAL]
# 	39 : Energy [NUMERICAL]
# 	38 : TotalEnergy [NUMERICAL]
# 	38 : RobustMeanAbsoluteDeviation [NUMERICAL]
# 	29 : Variance [NUMERICAL]
# 	25 : MeanAbsoluteDeviation [NUMERICAL]
# 	17 : InterquartileRange [NUMERICAL]
#
# Attribute in nodes with depth <= 0:
# 	33 : Median [NUMERICAL]
# 	12 : 10Percentile [NUMERICAL]
# 	8 : RootMeanSquared [NUMERICAL]
# 	7 : Energy [NUMERICAL]
# 	6 : Maximum [NUMERICAL]
# 	5 : TotalEnergy [NUMERICAL]
# 	5 : Minimum [NUMERICAL]
# 	4 : Range [NUMERICAL]
# 	4 : 90Percentile [NUMERICAL]
# 	2 : Skewness [NUMERICAL]
# 	1 : Kurtosis [NUMERICAL]
# 	1 : Entropy [NUMERICAL]
#
# Attribute in nodes with depth <= 1:
# 	51 : Median [NUMERICAL]
# 	36 : Minimum [NUMERICAL]
# 	33 : 10Percentile [NUMERICAL]
# 	27 : Entropy [NUMERICAL]
# 	22 : 90Percentile [NUMERICAL]
# 	16 : Maximum [NUMERICAL]
# 	12 : Skewness [NUMERICAL]
# 	11 : RootMeanSquared [NUMERICAL]
# 	10 : Uniformity [NUMERICAL]
# 	9 : Range [NUMERICAL]
# 	8 : TotalEnergy [NUMERICAL]
# 	8 : RobustMeanAbsoluteDeviation [NUMERICAL]
# 	8 : Energy [NUMERICAL]
# 	4 : MeanAbsoluteDeviation [NUMERICAL]
# 	4 : Kurtosis [NUMERICAL]
# 	3 : Mean [NUMERICAL]
# 	1 : Variance [NUMERICAL]
# 	1 : InterquartileRange [NUMERICAL]
#
# Attribute in nodes with depth <= 2:
# 	72 : Median [NUMERICAL]
# 	62 : Minimum [NUMERICAL]
# 	49 : Entropy [NUMERICAL]
# 	49 : 10Percentile [NUMERICAL]
# 	40 : Skewness [NUMERICAL]
# 	38 : 90Percentile [NUMERICAL]
# 	34 : Range [NUMERICAL]
# 	33 : Maximum [NUMERICAL]
# 	29 : Kurtosis [NUMERICAL]
# 	28 : Uniformity [NUMERICAL]
# 	22 : Mean [NUMERICAL]
# 	19 : Energy [NUMERICAL]
# 	18 : MeanAbsoluteDeviation [NUMERICAL]
# 	16 : TotalEnergy [NUMERICAL]
# 	15 : RootMeanSquared [NUMERICAL]
# 	12 : RobustMeanAbsoluteDeviation [NUMERICAL]
# 	10 : Variance [NUMERICAL]
# 	8 : InterquartileRange [NUMERICAL]
#
# Attribute in nodes with depth <= 3:
# 	111 : Median [NUMERICAL]
# 	101 : Entropy [NUMERICAL]
# 	100 : Minimum [NUMERICAL]
# 	73 : 10Percentile [NUMERICAL]
# 	67 : 90Percentile [NUMERICAL]
# 	62 : Skewness [NUMERICAL]
# 	56 : Range [NUMERICAL]
# 	56 : Maximum [NUMERICAL]
# 	50 : Mean [NUMERICAL]
# 	48 : Uniformity [NUMERICAL]
# 	44 : Kurtosis [NUMERICAL]
# 	28 : RobustMeanAbsoluteDeviation [NUMERICAL]
# 	28 : Energy [NUMERICAL]
# 	27 : TotalEnergy [NUMERICAL]
# 	27 : RootMeanSquared [NUMERICAL]
# 	21 : MeanAbsoluteDeviation [NUMERICAL]
# 	15 : Variance [NUMERICAL]
# 	12 : InterquartileRange [NUMERICAL]
#
# Attribute in nodes with depth <= 5:
# 	148 : Median [NUMERICAL]
# 	144 : Minimum [NUMERICAL]
# 	139 : Entropy [NUMERICAL]
# 	107 : Skewness [NUMERICAL]
# 	106 : 90Percentile [NUMERICAL]
# 	92 : Range [NUMERICAL]
# 	89 : 10Percentile [NUMERICAL]
# 	80 : Maximum [NUMERICAL]
# 	74 : Kurtosis [NUMERICAL]
# 	66 : Mean [NUMERICAL]
# 	61 : Uniformity [NUMERICAL]
# 	40 : RootMeanSquared [NUMERICAL]
# 	39 : Energy [NUMERICAL]
# 	38 : TotalEnergy [NUMERICAL]
# 	38 : RobustMeanAbsoluteDeviation [NUMERICAL]
# 	29 : Variance [NUMERICAL]
# 	25 : MeanAbsoluteDeviation [NUMERICAL]
# 	17 : InterquartileRange [NUMERICAL]
#
# Condition type in nodes:
# 	1332 : HigherCondition
# Condition type in nodes with depth <= 0:
# 	88 : HigherCondition
# Condition type in nodes with depth <= 1:
# 	264 : HigherCondition
# Condition type in nodes with depth <= 2:
# 	554 : HigherCondition
# Condition type in nodes with depth <= 3:
# 	926 : HigherCondition
# Condition type in nodes with depth <= 5:
# 	1332 : HigherCondition
#
# Training logs:
# Number of iteration to final model: 88
# 	Iter:1 train-loss:1.218648 valid-loss:1.222939  train-accuracy:0.958501 valid-accuracy:0.945346
# 	Iter:2 train-loss:1.080904 valid-loss:1.091228  train-accuracy:0.964225 valid-accuracy:0.959009
# 	Iter:3 train-loss:0.967674 valid-loss:0.982752  train-accuracy:0.964180 valid-accuracy:0.959009
# 	Iter:4 train-loss:0.871943 valid-loss:0.885901  train-accuracy:0.967042 valid-accuracy:0.972673
# 	Iter:5 train-loss:0.786857 valid-loss:0.799560  train-accuracy:0.974197 valid-accuracy:0.972673
# 	Iter:6 train-loss:0.707281 valid-loss:0.722695  train-accuracy:0.981352 valid-accuracy:0.972673
# 	Iter:16 train-loss:0.288449 valid-loss:0.318721  train-accuracy:0.992845 valid-accuracy:0.986336
# 	Iter:26 train-loss:0.138514 valid-loss:0.183357  train-accuracy:0.997138 valid-accuracy:1.000000
# 	Iter:36 train-loss:0.073638 valid-loss:0.126732  train-accuracy:0.998569 valid-accuracy:0.986336
# 	Iter:46 train-loss:0.047520 valid-loss:0.101681  train-accuracy:0.998569 valid-accuracy:1.000000
# 	Iter:56 train-loss:0.029988 valid-loss:0.077670  train-accuracy:1.000000 valid-accuracy:1.000000
# 	Iter:66 train-loss:0.020124 valid-loss:0.062959  train-accuracy:1.000000 valid-accuracy:1.000000
# 	Iter:76 train-loss:0.012402 valid-loss:0.057103  train-accuracy:1.000000 valid-accuracy:0.986336
# 	Iter:86 train-loss:0.008012 valid-loss:0.046774  train-accuracy:1.000000 valid-accuracy:1.000000
# 	Iter:96 train-loss:0.004884 valid-loss:0.050430  train-accuracy:1.000000 valid-accuracy:1.000000
# 	Iter:106 train-loss:0.003039 valid-loss:0.049669  train-accuracy:1.000000 valid-accuracy:1.000000
# 	Iter:116 train-loss:0.001933 valid-loss:0.047268  train-accuracy:1.000000 valid-accuracy:1.000000

# %%
# Model features
model.make_inspector().features()
# Out:
# ["10Percentile" (1; #0),
#  "90Percentile" (1; #1),
#  "Energy" (1; #2),
#  "Entropy" (1; #3),
#  "InterquartileRange" (1; #4),
#  "Kurtosis" (1; #5),
#  "Maximum" (1; #6),
#  "Mean" (1; #7),
#  "MeanAbsoluteDeviation" (1; #8),
#  "Median" (1; #9),
#  "Minimum" (1; #10),
#  "Range" (1; #11),
#  "RobustMeanAbsoluteDeviation" (1; #12),
#  "RootMeanSquared" (1; #13),
#  "Skewness" (1; #14),
#  "TotalEnergy" (1; #15),
#  "Uniformity" (1; #16),
#  "Variance" (1; #17)]

# %%
# Feature importance
model.make_inspector().variable_importances()
# Out:
# {'INV_MEAN_MIN_DEPTH': [("Median" (1; #9), 0.3005024818810186),
#   ("Minimum" (1; #10), 0.23966319260670074),
#   ("10Percentile" (1; #0), 0.2295482956994338),
#   ("Entropy" (1; #3), 0.22743410122798488),
#   ("90Percentile" (1; #1), 0.2153291890420766),
#   ("Maximum" (1; #6), 0.21281979746109347),
#   ("RootMeanSquared" (1; #13), 0.20946775878038085),
#   ("Range" (1; #11), 0.20915708428108987),
#   ("Skewness" (1; #14), 0.2089555761932845),
#   ("Energy" (1; #2), 0.20686640837446021),
#   ("TotalEnergy" (1; #15), 0.20383587239008116),
#   ("Uniformity" (1; #16), 0.20339603568445663),
#   ("Kurtosis" (1; #5), 0.2022267957240981),
#   ("Mean" (1; #7), 0.19905041698174683),
#   ("RobustMeanAbsoluteDeviation" (1; #12), 0.19685115753277382),
#   ("MeanAbsoluteDeviation" (1; #8), 0.1965517659467339),
#   ("Variance" (1; #17), 0.19294260407502203),
#   ("InterquartileRange" (1; #4), 0.19184365136514897)],
#  'SUM_SCORE': [("Energy" (1; #2), 189.20436940937793),
#   ("RootMeanSquared" (1; #13), 98.27419139957107),
#   ("Median" (1; #9), 69.07888318158584),
#   ("90Percentile" (1; #1), 30.777629225842855),
#   ("Skewness" (1; #14), 25.9967621106929),
#   ("Entropy" (1; #3), 24.517570202325835),
#   ("Minimum" (1; #10), 23.997962776887064),
#   ("10Percentile" (1; #0), 15.1182844646977),
#   ("Kurtosis" (1; #5), 13.882534680443735),
#   ("Uniformity" (1; #16), 11.356845208049325),
#   ("MeanAbsoluteDeviation" (1; #8), 8.579887517266995),
#   ("Range" (1; #11), 8.055329894880654),
#   ("Maximum" (1; #6), 6.361433465990539),
#   ("Mean" (1; #7), 3.829758476085778),
#   ("Variance" (1; #17), 3.6311620512381544),
#   ("TotalEnergy" (1; #15), 3.1797037647000512),
#   ("RobustMeanAbsoluteDeviation" (1; #12), 2.96723423371963),
#   ("InterquartileRange" (1; #4), 2.107553357979523)],
#  'NUM_AS_ROOT': [("Median" (1; #9), 33.0),
#   ("10Percentile" (1; #0), 12.0),
#   ("RootMeanSquared" (1; #13), 8.0),
#   ("Energy" (1; #2), 7.0),
#   ("Maximum" (1; #6), 6.0),
#   ("Minimum" (1; #10), 5.0),
#   ("TotalEnergy" (1; #15), 5.0),
#   ("90Percentile" (1; #1), 4.0),
#   ("Range" (1; #11), 4.0),
#   ("Skewness" (1; #14), 2.0),
#   ("Entropy" (1; #3), 1.0),
#   ("Kurtosis" (1; #5), 1.0)],
#  'NUM_NODES': [("Median" (1; #9), 148.0),
#   ("Minimum" (1; #10), 144.0),
#   ("Entropy" (1; #3), 139.0),
#   ("Skewness" (1; #14), 107.0),
#   ("90Percentile" (1; #1), 106.0),
#   ("Range" (1; #11), 92.0),
#   ("10Percentile" (1; #0), 89.0),
#   ("Maximum" (1; #6), 80.0),
#   ("Kurtosis" (1; #5), 74.0),
#   ("Mean" (1; #7), 66.0),
#   ("Uniformity" (1; #16), 61.0),
#   ("RootMeanSquared" (1; #13), 40.0),
#   ("Energy" (1; #2), 39.0),
#   ("RobustMeanAbsoluteDeviation" (1; #12), 38.0),
#   ("TotalEnergy" (1; #15), 38.0),
#   ("Variance" (1; #17), 29.0),
#   ("MeanAbsoluteDeviation" (1; #8), 25.0),
#   ("InterquartileRange" (1; #4), 17.0)]}

# %%
# Model self evaluation
model.make_inspector().evaluation()
# Out:
# Evaluation(num_examples=None, accuracy=1.0, loss=0.04515824839472771, rmse=None, ndcg=None, aucs=None, auuc=None, qini=None)

# %%
logs = model.make_inspector().training_logs()

plt.figure(figsize=(12, 4))
plt.subplot(1, 2, 1)
plt.plot([log.num_trees for log in logs], [log.evaluation.accuracy for log in logs])
plt.xlabel("Number of trees")
plt.ylabel("Accuracy (out-of-bag)")
plt.subplot(1, 2, 2)
plt.plot([log.num_trees for log in logs], [log.evaluation.loss for log in logs])
plt.xlabel("Number of trees")
plt.ylabel("Logloss (out-of-bag)")
plt.show()

# %% [markdown]
# Calculate the score of our hold-out validation dataset

# %%
predictions = model.predict(val_ds)
y_true      = validation_data["label"]

from sklearn.metrics import roc_auc_score
ROC_AUC = roc_auc_score(y_true, predictions)
print("The ROC AUC score is %.5f" % ROC_AUC )
# Out:
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 60ms/step
# The ROC AUC score is 1.00000

# %%
# Compute binary classification metrics with sklearn
import numpy as np
from sklearn.metrics import (
    accuracy_score,
    precision_score,
    recall_score,
    f1_score,
    roc_auc_score,
    average_precision_score,
    confusion_matrix,
    classification_report,
    matthews_corrcoef,
    log_loss,
    brier_score_loss,
)

# Get predictions (probabilities or class labels)
preds = model.predict(test_ds)
# If model outputs probabilities, convert to labels by threshold 0.5
if preds.ndim == 2:
    # For TFDF classification, preds may be class probabilities with shape (N, 2)
    if preds.shape[1] == 2:
        pos_probs = preds[:, 1]
    else:
        # If single-probability column (positive class)
        pos_probs = preds[:, -1]
    y_pred = (pos_probs >= 0.5).astype(int)
else:
    # Already class labels
    y_pred = preds.astype(int)
    pos_probs = None

# Ground truth labels (must be 0/1 integers)
y_true = test_data["label"].astype(int).to_numpy()

# Core metrics
metrics = {}
metrics["accuracy"] = accuracy_score(y_true, y_pred)
metrics["precision"] = precision_score(y_true, y_pred, zero_division=0)
metrics["recall"] = recall_score(y_true, y_pred, zero_division=0)
metrics["f1"] = f1_score(y_true, y_pred, zero_division=0)
metrics["mcc"] = matthews_corrcoef(y_true, y_pred)

# Probabilistic metrics (only if we have probabilities)
if pos_probs is not None:
    metrics["roc_auc"] = roc_auc_score(y_true, pos_probs)
    metrics["pr_auc"] = average_precision_score(y_true, pos_probs)
    metrics["log_loss"] = log_loss(y_true, pos_probs, labels=[0,1])
    metrics["brier_score"] = brier_score_loss(y_true, pos_probs)

# Confusion matrix and detailed report
cm = confusion_matrix(y_true, y_pred, labels=[0,1])
report = classification_report(y_true, y_pred, digits=4)

print("Sklearn binary metrics:")
for k, v in metrics.items():
    print(f"{k}: {v:.4f}")
print("\nConfusion matrix:\n", cm)
print("\nClassification report:\n", report)
# Out:
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 58ms/step
# Sklearn binary metrics:
# accuracy: 0.8760
# precision: 0.5294
# recall: 0.5294
# f1: 0.5294
# mcc: 0.4580
# roc_auc: 0.8976
# pr_auc: 0.7160
# log_loss: 0.3508
# brier_score: 0.0847
#
# Confusion matrix:
#  [[104   8]
#  [  8   9]]
#
# Classification report:
#                precision    recall  f1-score   support
#
#            0     0.9286    0.9286    0.9286       112
#            1     0.5294    0.5294    0.5294        17
#
#     accuracy                         0.8760       129
#    macro avg     0.7290    0.7290    0.7290       129
# weighted avg     0.8760    0.8760    0.8760       129
