# %%
# Import packages and modules
import numpy  as np
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow_decision_forests as tfdf

from sklearn.model_selection import train_test_split
# Out:
# 2026-08-15 05:05:22.306434: I tensorflow/core/util/port.cc:113] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2026-08-15 05:05:22.678527: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2026-08-15 05:05:27.500978: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
# Check the version of TensorFlow Decision Forests
print("Found TensorFlow Decision Forests v" + tfdf.__version__)
# Out:
# Found TensorFlow Decision Forests v1.9.1

# %%
datasetPath = 'dataset/firstorder/kernel5/dataset.csv'

# %%
# Parameters
datasetPath = "dataset/firstorder/kernel6/1.dataset.csv"

# %%
# train/validation/test = 70/10/20
dataset = pd.read_csv(datasetPath)

train_data, temp_data = train_test_split(dataset, test_size=0.3, random_state=42)
validation_data, test_data = train_test_split(temp_data, test_size=2/3, random_state=42)

# %%
from sklearn.utils.class_weight import compute_class_weight

# tinh class weight tren tap train
classes = np.array([0, 1])
weights = compute_class_weight(class_weight="balanced", classes=classes, y=train_data["label"])
class_weight = {0: weights[0], 1: weights[1]}

# gan sample_weight cho tung dong
train_data["sample_weight"] = train_data["label"].map(class_weight)
validation_data["sample_weight"] = validation_data["label"].map(class_weight)
test_data["sample_weight"] = test_data["label"].map(class_weight)

# Convert the dataset into a TensorFlow dataset.
train_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    train_data, label="label", weight="sample_weight"
)         
val_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    validation_data, label="label", weight="sample_weight"
)
test_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    test_data, label="label", weight="sample_weight"
)
# Out:
# 2026-08-15 05:05:40.338034: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:984] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2026-08-15 05:05:40.339581: W tensorflow/core/common_runtime/gpu/gpu_device.cc:2251] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...

# %%
import keras

# %%
# %%time

# Train a Gradient Boosted Trees model.
model = tfdf.keras.GradientBoostedTreesModel()

# Add evaluation metrics
model.compile(
    metrics=["accuracy"]
)
model.fit(x=train_ds)

# # Train a Gradient Boosted Trees model.
# model = tfdf.keras.GradientBoostedTreesModel(num_trees=1500)
# model.fit(train_ds)
# Out:
# Use /tmp/tmpm92xpwrl as temporary training directory
# Reading training dataset...
# [WARNING 26-08-15 05:05:40.4958 UTC gradient_boosted_trees.cc:1840] "goss_alpha" set but "sampling_method" not equal to "GOSS".
# [WARNING 26-08-15 05:05:40.4960 UTC gradient_boosted_trees.cc:1851] "goss_beta" set but "sampling_method" not equal to "GOSS".
# [WARNING 26-08-15 05:05:40.4960 UTC gradient_boosted_trees.cc:1865] "selective_gradient_boosting_ratio" set but "sampling_method" not equal to "SELGB".
# Training dataset read in 0:00:02.650678. Found 507 examples.
# Training model...
# Model trained in 0:00:00.172734
# Compiling model...
# [INFO 26-08-15 05:05:43.3487 UTC kernel.cc:1233] Loading model from path /tmp/tmpm92xpwrl/model/ with prefix c463382190154bc1
# [INFO 26-08-15 05:05:43.3504 UTC quick_scorer_extended.cc:911] The binary was compiled without AVX2 support, but your CPU supports it. Enable it for faster model inference.
# [INFO 26-08-15 05:05:43.3505 UTC abstract_model.cc:1362] Engine "GradientBoostedTreesQuickScorerExtended" built
# [INFO 26-08-15 05:05:43.3505 UTC kernel.cc:1061] Use fast generic engine
# Model compiled.
# CPU times: user 5.68 s, sys: 257 ms, total: 5.93 s
# Wall time: 6.12 s

# %%
# Evaluate the model
evaluate = model.evaluate(val_ds, return_dict=True)
print()

for name, value in evaluate.items():
    print(f"{name}: {value:.4f}")
# Out:
# WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 1/1 [==============================] - ETA: 0s - loss: 0.0000e+00 - accuracy: 0.9861
# 1/1 [==============================] - 3s 3s/step - loss: 0.0000e+00 - accuracy: 0.9861
# loss: 0.0000
# accuracy: 0.9861

# %%
# Model Summary
model.summary()
# Out:
# Model: "gradient_boosted_trees_model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
# =================================================================
# Total params: 1 (1.00 Byte)
# Trainable params: 0 (0.00 Byte)
# Non-trainable params: 1 (1.00 Byte)
# _________________________________________________________________
# Type: "GRADIENT_BOOSTED_TREES"
# Task: CLASSIFICATION
# Label: "__LABEL"
#
# Input Features (18):
# 	10Percentile
# 	90Percentile
# 	Energy
# 	Entropy
# 	InterquartileRange
# 	Kurtosis
# 	Maximum
# 	Mean
# 	MeanAbsoluteDeviation
# 	Median
# 	Minimum
# 	Range
# 	RobustMeanAbsoluteDeviation
# 	RootMeanSquared
# 	Skewness
# 	TotalEnergy
# 	Uniformity
# 	Variance
#
# Trained with weights
#
# Variable Importance: INV_MEAN_MIN_DEPTH:
#     1.                "90Percentile"  1.000000 ################
#     2.                    "Skewness"  0.345477 ##
#     3.                     "Minimum"  0.275312
#     4.                     "Entropy"  0.268379
#     5.                    "Kurtosis"  0.250733
#     6.                     "Maximum"  0.239695
#     7.                    "Variance"  0.238500
#     8.                "10Percentile"  0.234363
#     9.                       "Range"  0.231962
#    10. "RobustMeanAbsoluteDeviation"  0.231853
#    11.                        "Mean"  0.231787
#    12.                 "TotalEnergy"  0.231649
#    13.                      "Median"  0.231499
#    14.                  "Uniformity"  0.231362
#    15.                      "Energy"  0.229923
#    16.             "RootMeanSquared"  0.229904
#    17.       "MeanAbsoluteDeviation"  0.228983
#    18.          "InterquartileRange"  0.228827
#
# Variable Importance: NUM_AS_ROOT:
#     1. "90Percentile" 30.000000
#
# Variable Importance: NUM_NODES:
#     1.                "90Percentile" 37.000000 ################
#     2.                     "Minimum" 29.000000 ############
#     3.                    "Skewness" 29.000000 ############
#     4.                     "Entropy" 19.000000 #######
#     5.                    "Kurtosis" 13.000000 #####
#     6.                    "Variance" 13.000000 #####
#     7.                "10Percentile" 11.000000 ####
#     8.                     "Maximum"  9.000000 ###
#     9.                        "Mean"  8.000000 ##
#    10.                      "Median"  8.000000 ##
#    11.                       "Range"  6.000000 #
#    12. "RobustMeanAbsoluteDeviation"  5.000000 #
#    13.                 "TotalEnergy"  5.000000 #
#    14.                  "Uniformity"  5.000000 #
#    15.                      "Energy"  4.000000
#    16.          "InterquartileRange"  3.000000
#    17.             "RootMeanSquared"  3.000000
#    18.       "MeanAbsoluteDeviation"  2.000000
#
# Variable Importance: SUM_SCORE:
#     1.                "90Percentile" 576.845938 ################
#     2.                     "Minimum" 20.509810
#     3.                    "Skewness"  9.307582
#     4.                    "Kurtosis"  5.201618
#     5.                     "Entropy"  4.208911
#     6.                     "Maximum"  1.202728
#     7.                    "Variance"  0.560108
#     8.                      "Median"  0.175828
#     9.                       "Range"  0.092483
#    10.                        "Mean"  0.050496
#    11.                "10Percentile"  0.036345
#    12.                      "Energy"  0.034406
#    13.                  "Uniformity"  0.008564
#    14.          "InterquartileRange"  0.008504
#    15.       "MeanAbsoluteDeviation"  0.006838
#    16.                 "TotalEnergy"  0.005831
#    17.             "RootMeanSquared"  0.001211
#    18. "RobustMeanAbsoluteDeviation"  0.000000
#
#
#
# Loss: BINOMIAL_LOG_LIKELIHOOD
# Validation loss value: 0.201139
# Number of trees per iteration: 1
# Node format: NOT_SET
# Number of trees: 30
# Total number of nodes: 448
#
# Number of nodes by tree:
# Count: 30 Average: 14.9333 StdDev: 1.59025
# Min: 11 Max: 19 Ignored: 0
# ----------------------------------------------
# [ 11, 12)  1   3.33%   3.33% #
# [ 12, 13)  0   0.00%   3.33%
# [ 13, 14)  6  20.00%  23.33% ####
# [ 14, 15)  0   0.00%  23.33%
# [ 15, 16) 17  56.67%  80.00% ##########
# [ 16, 17)  0   0.00%  80.00%
# [ 17, 18)  5  16.67%  96.67% ###
# [ 18, 19)  0   0.00%  96.67%
# [ 19, 19]  1   3.33% 100.00% #
#
# Depth by leafs:
# Count: 239 Average: 3.40586 StdDev: 1.15282
# Min: 1 Max: 5 Ignored: 0
# ----------------------------------------------
# [ 1, 2)  1   0.42%   0.42%
# [ 2, 3) 63  26.36%  26.78% ########
# [ 3, 4) 77  32.22%  59.00% ##########
# [ 4, 5) 34  14.23%  73.22% ####
# [ 5, 5] 64  26.78% 100.00% ########
#
# Number of training obs by leaf:
# Count: 239 Average: 57.4895 StdDev: 114.152
# Min: 5 Max: 413 Ignored: 0
# ----------------------------------------------
# [   5,  25) 181  75.73%  75.73% ##########
# [  25,  45)  10   4.18%  79.92% #
# [  45,  66)   7   2.93%  82.85%
# [  66,  86)   6   2.51%  85.36%
# [  86, 107)   2   0.84%  86.19%
# [ 107, 127)   1   0.42%  86.61%
# [ 127, 148)   2   0.84%  87.45%
# [ 148, 168)   0   0.00%  87.45%
# [ 168, 189)   0   0.00%  87.45%
# [ 189, 209)   0   0.00%  87.45%
# [ 209, 229)   1   0.42%  87.87%
# [ 229, 250)   0   0.00%  87.87%
# [ 250, 270)   2   0.84%  88.70%
# [ 270, 291)   0   0.00%  88.70%
# [ 291, 311)   2   0.84%  89.54%
# [ 311, 332)   4   1.67%  91.21%
# [ 332, 352)   5   2.09%  93.31%
# [ 352, 373)   3   1.26%  94.56%
# [ 373, 393)   7   2.93%  97.49%
# [ 393, 413]   6   2.51% 100.00%
#
# Attribute in nodes:
# 	37 : 90Percentile [NUMERICAL]
# 	29 : Skewness [NUMERICAL]
# 	29 : Minimum [NUMERICAL]
# 	19 : Entropy [NUMERICAL]
# 	13 : Variance [NUMERICAL]
# 	13 : Kurtosis [NUMERICAL]
# 	11 : 10Percentile [NUMERICAL]
# 	9 : Maximum [NUMERICAL]
# 	8 : Median [NUMERICAL]
# 	8 : Mean [NUMERICAL]
# 	6 : Range [NUMERICAL]
# 	5 : Uniformity [NUMERICAL]
# 	5 : TotalEnergy [NUMERICAL]
# 	5 : RobustMeanAbsoluteDeviation [NUMERICAL]
# 	4 : Energy [NUMERICAL]
# 	3 : RootMeanSquared [NUMERICAL]
# 	3 : InterquartileRange [NUMERICAL]
# 	2 : MeanAbsoluteDeviation [NUMERICAL]
#
# Attribute in nodes with depth <= 0:
# 	30 : 90Percentile [NUMERICAL]
#
# Attribute in nodes with depth <= 1:
# 	32 : 90Percentile [NUMERICAL]
# 	23 : Skewness [NUMERICAL]
# 	5 : Minimum [NUMERICAL]
# 	4 : TotalEnergy [NUMERICAL]
# 	4 : Kurtosis [NUMERICAL]
# 	3 : Variance [NUMERICAL]
# 	3 : 10Percentile [NUMERICAL]
# 	2 : Uniformity [NUMERICAL]
# 	2 : RobustMeanAbsoluteDeviation [NUMERICAL]
# 	2 : Median [NUMERICAL]
# 	2 : Maximum [NUMERICAL]
# 	2 : Entropy [NUMERICAL]
# 	1 : Range [NUMERICAL]
# 	1 : MeanAbsoluteDeviation [NUMERICAL]
# 	1 : Mean [NUMERICAL]
# 	1 : InterquartileRange [NUMERICAL]
# 	1 : Energy [NUMERICAL]
#
# Attribute in nodes with depth <= 2:
# 	34 : 90Percentile [NUMERICAL]
# 	28 : Skewness [NUMERICAL]
# 	19 : Entropy [NUMERICAL]
# 	12 : Minimum [NUMERICAL]
# 	9 : Maximum [NUMERICAL]
# 	8 : 10Percentile [NUMERICAL]
# 	5 : Variance [NUMERICAL]
# 	5 : Kurtosis [NUMERICAL]
# 	4 : TotalEnergy [NUMERICAL]
# 	3 : Uniformity [NUMERICAL]
# 	3 : RobustMeanAbsoluteDeviation [NUMERICAL]
# 	3 : Median [NUMERICAL]
# 	3 : Energy [NUMERICAL]
# 	2 : RootMeanSquared [NUMERICAL]
# 	2 : Mean [NUMERICAL]
# 	2 : InterquartileRange [NUMERICAL]
# 	1 : Range [NUMERICAL]
# 	1 : MeanAbsoluteDeviation [NUMERICAL]
#
# Attribute in nodes with depth <= 3:
# 	35 : 90Percentile [NUMERICAL]
# 	29 : Skewness [NUMERICAL]
# 	24 : Minimum [NUMERICAL]
# 	19 : Entropy [NUMERICAL]
# 	12 : Kurtosis [NUMERICAL]
# 	11 : Variance [NUMERICAL]
# 	9 : Maximum [NUMERICAL]
# 	9 : 10Percentile [NUMERICAL]
# 	4 : Uniformity [NUMERICAL]
# 	4 : TotalEnergy [NUMERICAL]
# 	4 : RobustMeanAbsoluteDeviation [NUMERICAL]
# 	3 : Range [NUMERICAL]
# 	3 : Median [NUMERICAL]
# 	3 : Mean [NUMERICAL]
# 	3 : Energy [NUMERICAL]
# 	2 : RootMeanSquared [NUMERICAL]
# 	2 : InterquartileRange [NUMERICAL]
# 	1 : MeanAbsoluteDeviation [NUMERICAL]
#
# Attribute in nodes with depth <= 5:
# 	37 : 90Percentile [NUMERICAL]
# 	29 : Skewness [NUMERICAL]
# 	29 : Minimum [NUMERICAL]
# 	19 : Entropy [NUMERICAL]
# 	13 : Variance [NUMERICAL]
# 	13 : Kurtosis [NUMERICAL]
# 	11 : 10Percentile [NUMERICAL]
# 	9 : Maximum [NUMERICAL]
# 	8 : Median [NUMERICAL]
# 	8 : Mean [NUMERICAL]
# 	6 : Range [NUMERICAL]
# 	5 : Uniformity [NUMERICAL]
# 	5 : TotalEnergy [NUMERICAL]
# 	5 : RobustMeanAbsoluteDeviation [NUMERICAL]
# 	4 : Energy [NUMERICAL]
# 	3 : RootMeanSquared [NUMERICAL]
# 	3 : InterquartileRange [NUMERICAL]
# 	2 : MeanAbsoluteDeviation [NUMERICAL]
#
# Condition type in nodes:
# 	209 : HigherCondition
# Condition type in nodes with depth <= 0:
# 	30 : HigherCondition
# Condition type in nodes with depth <= 1:
# 	89 : HigherCondition
# Condition type in nodes with depth <= 2:
# 	144 : HigherCondition
# Condition type in nodes with depth <= 3:
# 	177 : HigherCondition
# Condition type in nodes with depth <= 5:
# 	209 : HigherCondition
#
# Training logs:
# Number of iteration to final model: 30
# 	Iter:1 train-loss:1.201276 valid-loss:1.212121  train-accuracy:0.992002 valid-accuracy:0.974619
# 	Iter:2 train-loss:1.050047 valid-loss:1.064469  train-accuracy:0.992002 valid-accuracy:0.974619
# 	Iter:3 train-loss:0.923988 valid-loss:0.941403  train-accuracy:0.992002 valid-accuracy:0.974619
# 	Iter:4 train-loss:0.817467 valid-loss:0.838836  train-accuracy:0.992002 valid-accuracy:0.974619
# 	Iter:5 train-loss:0.724198 valid-loss:0.752558  train-accuracy:0.992002 valid-accuracy:0.974619
# 	Iter:6 train-loss:0.643993 valid-loss:0.678495  train-accuracy:0.992002 valid-accuracy:0.974619
# 	Iter:16 train-loss:0.223529 valid-loss:0.301414  train-accuracy:0.996572 valid-accuracy:0.974619
# 	Iter:26 train-loss:0.090755 valid-loss:0.209198  train-accuracy:0.997715 valid-accuracy:0.974619
# 	Iter:36 train-loss:0.031589 valid-loss:0.208953  train-accuracy:1.000000 valid-accuracy:0.974619
# 	Iter:46 train-loss:0.011388 valid-loss:0.242482  train-accuracy:1.000000 valid-accuracy:0.974619
# 	Iter:56 train-loss:0.004165 valid-loss:0.286942  train-accuracy:1.000000 valid-accuracy:0.974619

# %%
# Model features
model.make_inspector().features()
# Out:
# ["10Percentile" (1; #0),
#  "90Percentile" (1; #1),
#  "Energy" (1; #2),
#  "Entropy" (1; #3),
#  "InterquartileRange" (1; #4),
#  "Kurtosis" (1; #5),
#  "Maximum" (1; #6),
#  "Mean" (1; #7),
#  "MeanAbsoluteDeviation" (1; #8),
#  "Median" (1; #9),
#  "Minimum" (1; #10),
#  "Range" (1; #11),
#  "RobustMeanAbsoluteDeviation" (1; #12),
#  "RootMeanSquared" (1; #13),
#  "Skewness" (1; #14),
#  "TotalEnergy" (1; #15),
#  "Uniformity" (1; #16),
#  "Variance" (1; #17)]

# %%
# Feature importance
model.make_inspector().variable_importances()
# Out:
# {'INV_MEAN_MIN_DEPTH': [("90Percentile" (1; #1), 1.0),
#   ("Skewness" (1; #14), 0.34547681283930753),
#   ("Minimum" (1; #10), 0.2753115463331852),
#   ("Entropy" (1; #3), 0.26837918144349654),
#   ("Kurtosis" (1; #5), 0.2507329627615118),
#   ("Maximum" (1; #6), 0.23969486463264225),
#   ("Variance" (1; #17), 0.23850009937504144),
#   ("10Percentile" (1; #0), 0.2343633748325976),
#   ("Range" (1; #11), 0.23196160973993302),
#   ("RobustMeanAbsoluteDeviation" (1; #12), 0.23185347841554524),
#   ("Mean" (1; #7), 0.2317873688147878),
#   ("TotalEnergy" (1; #15), 0.23164887423549743),
#   ("Median" (1; #9), 0.23149920230764284),
#   ("Uniformity" (1; #16), 0.23136175981833823),
#   ("Energy" (1; #2), 0.2299228116275251),
#   ("RootMeanSquared" (1; #13), 0.22990393299942521),
#   ("MeanAbsoluteDeviation" (1; #8), 0.22898266274124962),
#   ("InterquartileRange" (1; #4), 0.22882671824348255)],
#  'NUM_AS_ROOT': [("90Percentile" (1; #1), 30.0)],
#  'SUM_SCORE': [("90Percentile" (1; #1), 576.8459383036007),
#   ("Minimum" (1; #10), 20.50980967206829),
#   ("Skewness" (1; #14), 9.307581559448135),
#   ("Kurtosis" (1; #5), 5.2016179432170615),
#   ("Entropy" (1; #3), 4.208911367761445),
#   ("Maximum" (1; #6), 1.2027283010767118),
#   ("Variance" (1; #17), 0.5601082081460895),
#   ("Median" (1; #9), 0.17582787937184746),
#   ("Range" (1; #11), 0.0924833692920739),
#   ("Mean" (1; #7), 0.050496009037858884),
#   ("10Percentile" (1; #0), 0.03634479125539145),
#   ("Energy" (1; #2), 0.03440581556386009),
#   ("Uniformity" (1; #16), 0.008563879412581256),
#   ("InterquartileRange" (1; #4), 0.008504246975065473),
#   ("MeanAbsoluteDeviation" (1; #8), 0.006837686499197261),
#   ("TotalEnergy" (1; #15), 0.005830938978115624),
#   ("RootMeanSquared" (1; #13), 0.0012110666033944891),
#   ("RobustMeanAbsoluteDeviation" (1; #12), 6.2970463554799555e-16)],
#  'NUM_NODES': [("90Percentile" (1; #1), 37.0),
#   ("Minimum" (1; #10), 29.0),
#   ("Skewness" (1; #14), 29.0),
#   ("Entropy" (1; #3), 19.0),
#   ("Kurtosis" (1; #5), 13.0),
#   ("Variance" (1; #17), 13.0),
#   ("10Percentile" (1; #0), 11.0),
#   ("Maximum" (1; #6), 9.0),
#   ("Mean" (1; #7), 8.0),
#   ("Median" (1; #9), 8.0),
#   ("Range" (1; #11), 6.0),
#   ("RobustMeanAbsoluteDeviation" (1; #12), 5.0),
#   ("TotalEnergy" (1; #15), 5.0),
#   ("Uniformity" (1; #16), 5.0),
#   ("Energy" (1; #2), 4.0),
#   ("InterquartileRange" (1; #4), 3.0),
#   ("RootMeanSquared" (1; #13), 3.0),
#   ("MeanAbsoluteDeviation" (1; #8), 2.0)]}

# %%
# Model self evaluation
model.make_inspector().evaluation()
# Out:
# Evaluation(num_examples=None, accuracy=0.9746192693710327, loss=0.2011389136314392, rmse=None, ndcg=None, aucs=None, auuc=None, qini=None)

# %%
logs = model.make_inspector().training_logs()

plt.figure(figsize=(12, 4))
plt.subplot(1, 2, 1)
plt.plot([log.num_trees for log in logs], [log.evaluation.accuracy for log in logs])
plt.xlabel("Number of trees")
plt.ylabel("Accuracy (out-of-bag)")
plt.subplot(1, 2, 2)
plt.plot([log.num_trees for log in logs], [log.evaluation.loss for log in logs])
plt.xlabel("Number of trees")
plt.ylabel("Logloss (out-of-bag)")
plt.show()

# %% [markdown]
# Calculate the score of our hold-out validation dataset

# %%
predictions = model.predict(val_ds)
y_true      = validation_data["label"]

from sklearn.metrics import roc_auc_score
ROC_AUC = roc_auc_score(y_true, predictions)
print("The ROC AUC score is %.5f" % ROC_AUC )
# Out:
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 59ms/step
# The ROC AUC score is 1.00000

# %%
# Compute binary classification metrics with sklearn
import numpy as np
from sklearn.metrics import (
    accuracy_score,
    precision_score,
    recall_score,
    f1_score,
    roc_auc_score,
    average_precision_score,
    confusion_matrix,
    classification_report,
    matthews_corrcoef,
    log_loss,
    brier_score_loss,
)

# Get predictions (probabilities or class labels)
preds = model.predict(test_ds)
# If model outputs probabilities, convert to labels by threshold 0.5
if preds.ndim == 2:
    # For TFDF classification, preds may be class probabilities with shape (N, 2)
    if preds.shape[1] == 2:
        pos_probs = preds[:, 1]
    else:
        # If single-probability column (positive class)
        pos_probs = preds[:, -1]
    y_pred = (pos_probs >= 0.5).astype(int)
else:
    # Already class labels
    y_pred = preds.astype(int)
    pos_probs = None

# Ground truth labels (must be 0/1 integers)
y_true = test_data["label"].astype(int).to_numpy()

# Core metrics
metrics = {}
metrics["accuracy"] = accuracy_score(y_true, y_pred)
metrics["precision"] = precision_score(y_true, y_pred, zero_division=0)
metrics["recall"] = recall_score(y_true, y_pred, zero_division=0)
metrics["f1"] = f1_score(y_true, y_pred, zero_division=0)
metrics["mcc"] = matthews_corrcoef(y_true, y_pred)

# Probabilistic metrics (only if we have probabilities)
if pos_probs is not None:
    metrics["roc_auc"] = roc_auc_score(y_true, pos_probs)
    metrics["pr_auc"] = average_precision_score(y_true, pos_probs)
    metrics["log_loss"] = log_loss(y_true, pos_probs, labels=[0,1])
    metrics["brier_score"] = brier_score_loss(y_true, pos_probs)

# Confusion matrix and detailed report
cm = confusion_matrix(y_true, y_pred, labels=[0,1])
report = classification_report(y_true, y_pred, digits=4)

print("Sklearn binary metrics:")
for k, v in metrics.items():
    print(f"{k}: {v:.4f}")
print("\nConfusion matrix:\n", cm)
print("\nClassification report:\n", report)
# Out:
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 64ms/step
# Sklearn binary metrics:
# accuracy: 0.9726
# precision: 0.6667
# recall: 0.8571
# f1: 0.7500
# mcc: 0.7423
# roc_auc: 0.9969
# pr_auc: 0.9571
# log_loss: 0.0931
# brier_score: 0.0224
#
# Confusion matrix:
#  [[136   3]
#  [  1   6]]
#
# Classification report:
#                precision    recall  f1-score   support
#
#            0     0.9927    0.9784    0.9855       139
#            1     0.6667    0.8571    0.7500         7
#
#     accuracy                         0.9726       146
#    macro avg     0.8297    0.9178    0.8678       146
# weighted avg     0.9771    0.9726    0.9742       146
