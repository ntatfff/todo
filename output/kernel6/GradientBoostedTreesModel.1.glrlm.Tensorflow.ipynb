# %%
# Import packages and modules
import numpy  as np
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow_decision_forests as tfdf

from sklearn.model_selection import train_test_split
# Out:
# 2026-08-15 05:07:10.660232: I tensorflow/core/util/port.cc:113] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2026-08-15 05:07:11.005480: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2026-08-15 05:07:15.664970: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
# Check the version of TensorFlow Decision Forests
print("Found TensorFlow Decision Forests v" + tfdf.__version__)
# Out:
# Found TensorFlow Decision Forests v1.9.1

# %%
datasetPath = 'dataset/firstorder/kernel5/dataset.csv'

# %%
# Parameters
datasetPath = "dataset/glrlm/kernel6/1.dataset.csv"

# %%
# train/validation/test = 70/10/20
dataset = pd.read_csv(datasetPath)

train_data, temp_data = train_test_split(dataset, test_size=0.3, random_state=42)
validation_data, test_data = train_test_split(temp_data, test_size=2/3, random_state=42)

# %%
from sklearn.utils.class_weight import compute_class_weight

# tinh class weight tren tap train
classes = np.array([0, 1])
weights = compute_class_weight(class_weight="balanced", classes=classes, y=train_data["label"])
class_weight = {0: weights[0], 1: weights[1]}

# gan sample_weight cho tung dong
train_data["sample_weight"] = train_data["label"].map(class_weight)
validation_data["sample_weight"] = validation_data["label"].map(class_weight)
test_data["sample_weight"] = test_data["label"].map(class_weight)

# Convert the dataset into a TensorFlow dataset.
train_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    train_data, label="label", weight="sample_weight"
)         
val_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    validation_data, label="label", weight="sample_weight"
)
test_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    test_data, label="label", weight="sample_weight"
)
# Out:
# 2026-08-15 05:07:29.184367: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:984] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2026-08-15 05:07:29.185951: W tensorflow/core/common_runtime/gpu/gpu_device.cc:2251] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...

# %%
import keras

# %%
# %%time

# Train a Gradient Boosted Trees model.
model = tfdf.keras.GradientBoostedTreesModel()

# Add evaluation metrics
model.compile(
    metrics=["accuracy"]
)
model.fit(x=train_ds)

# # Train a Gradient Boosted Trees model.
# model = tfdf.keras.GradientBoostedTreesModel(num_trees=1500)
# model.fit(train_ds)
# Out:
# Use /tmp/tmprsyyf9w4 as temporary training directory
# Reading training dataset...
# [WARNING 26-08-15 05:07:29.3345 UTC gradient_boosted_trees.cc:1840] "goss_alpha" set but "sampling_method" not equal to "GOSS".
# [WARNING 26-08-15 05:07:29.3347 UTC gradient_boosted_trees.cc:1851] "goss_beta" set but "sampling_method" not equal to "GOSS".
# [WARNING 26-08-15 05:07:29.3347 UTC gradient_boosted_trees.cc:1865] "selective_gradient_boosting_ratio" set but "sampling_method" not equal to "SELGB".
# Training dataset read in 0:00:02.581668. Found 507 examples.
# Training model...
# Model trained in 0:00:00.763926
# Compiling model...
# [INFO 26-08-15 05:07:32.7027 UTC kernel.cc:1233] Loading model from path /tmp/tmprsyyf9w4/model/ with prefix cb9ce01a73764cf3
# [INFO 26-08-15 05:07:32.7096 UTC quick_scorer_extended.cc:911] The binary was compiled without AVX2 support, but your CPU supports it. Enable it for faster model inference.
# [INFO 26-08-15 05:07:32.7100 UTC abstract_model.cc:1362] Engine "GradientBoostedTreesQuickScorerExtended" built
# [INFO 26-08-15 05:07:32.7100 UTC kernel.cc:1061] Use fast generic engine
# Model compiled.
# CPU times: user 6.1 s, sys: 1.09 s, total: 7.19 s
# Wall time: 6.52 s

# %%
# Evaluate the model
evaluate = model.evaluate(val_ds, return_dict=True)
print()

for name, value in evaluate.items():
    print(f"{name}: {value:.4f}")
# Out:
# WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 1/1 [==============================] - ETA: 0s - loss: 0.0000e+00 - accuracy: 0.9722
# 1/1 [==============================] - 3s 3s/step - loss: 0.0000e+00 - accuracy: 0.9722
# loss: 0.0000
# accuracy: 0.9722

# %%
# Model Summary
model.summary()
# Out:
# Model: "gradient_boosted_trees_model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
# =================================================================
# Total params: 1 (1.00 Byte)
# Trainable params: 0 (0.00 Byte)
# Non-trainable params: 1 (1.00 Byte)
# _________________________________________________________________
# Type: "GRADIENT_BOOSTED_TREES"
# Task: CLASSIFICATION
# Label: "__LABEL"
#
# Input Features (16):
# 	GrayLevelNonUniformity
# 	GrayLevelNonUniformityNormalized
# 	GrayLevelVariance
# 	HighGrayLevelRunEmphasis
# 	LongRunEmphasis
# 	LongRunHighGrayLevelEmphasis
# 	LongRunLowGrayLevelEmphasis
# 	LowGrayLevelRunEmphasis
# 	RunEntropy
# 	RunLengthNonUniformity
# 	RunLengthNonUniformityNormalized
# 	RunPercentage
# 	RunVariance
# 	ShortRunEmphasis
# 	ShortRunHighGrayLevelEmphasis
# 	ShortRunLowGrayLevelEmphasis
#
# Trained with weights
#
# Variable Importance: INV_MEAN_MIN_DEPTH:
#     1.                "GrayLevelVariance"  0.538340 ################
#     2.     "ShortRunLowGrayLevelEmphasis"  0.257270 ##
#     3.         "HighGrayLevelRunEmphasis"  0.248948 ##
#     4.      "LongRunLowGrayLevelEmphasis"  0.235706 #
#     5.    "ShortRunHighGrayLevelEmphasis"  0.232375 #
#     6.          "LowGrayLevelRunEmphasis"  0.231065 #
#     7.                       "RunEntropy"  0.229534 #
#     8. "GrayLevelNonUniformityNormalized"  0.216261
#     9.           "GrayLevelNonUniformity"  0.208047
#    10.                      "RunVariance"  0.204856
#    11.                  "LongRunEmphasis"  0.204751
#    12.                 "ShortRunEmphasis"  0.202897
#    13.     "LongRunHighGrayLevelEmphasis"  0.202761
#    14.                    "RunPercentage"  0.200787
#    15. "RunLengthNonUniformityNormalized"  0.200568
#    16.           "RunLengthNonUniformity"  0.200188
#
# Variable Importance: NUM_AS_ROOT:
#     1.             "GrayLevelVariance" 187.000000 ################
#     2. "ShortRunHighGrayLevelEmphasis" 28.000000 ##
#     3.      "HighGrayLevelRunEmphasis" 22.000000 #
#     4.       "LowGrayLevelRunEmphasis" 21.000000 #
#     5.  "ShortRunLowGrayLevelEmphasis" 21.000000 #
#     6.   "LongRunLowGrayLevelEmphasis" 17.000000 #
#     7.                    "RunEntropy"  4.000000
#
# Variable Importance: NUM_NODES:
#     1.                "GrayLevelVariance" 711.000000 ################
#     2.    "ShortRunHighGrayLevelEmphasis" 260.000000 #####
#     3.                       "RunEntropy" 252.000000 #####
#     4.      "LongRunLowGrayLevelEmphasis" 242.000000 ####
#     5. "GrayLevelNonUniformityNormalized" 228.000000 ####
#     6.         "HighGrayLevelRunEmphasis" 213.000000 ####
#     7.     "ShortRunLowGrayLevelEmphasis" 180.000000 ###
#     8.           "GrayLevelNonUniformity" 148.000000 ##
#     9.                      "RunVariance" 119.000000 #
#    10.                 "ShortRunEmphasis" 114.000000 #
#    11.          "LowGrayLevelRunEmphasis" 97.000000 #
#    12.     "LongRunHighGrayLevelEmphasis" 84.000000 #
#    13.                  "LongRunEmphasis" 74.000000
#    14. "RunLengthNonUniformityNormalized" 73.000000
#    15.           "RunLengthNonUniformity" 43.000000
#    16.                    "RunPercentage" 42.000000
#
# Variable Importance: SUM_SCORE:
#     1.         "HighGrayLevelRunEmphasis" 476.487883 ################
#     2.                       "RunEntropy" 69.228500 ##
#     3.    "ShortRunHighGrayLevelEmphasis" 68.117736 ##
#     4.                "GrayLevelVariance" 11.392416
#     5.      "LongRunLowGrayLevelEmphasis"  4.584737
#     6.                    "RunPercentage"  3.884631
#     7.           "GrayLevelNonUniformity"  3.631542
#     8.     "ShortRunLowGrayLevelEmphasis"  3.613929
#     9.          "LowGrayLevelRunEmphasis"  1.004293
#    10.           "RunLengthNonUniformity"  0.581157
#    11.                      "RunVariance"  0.213501
#    12.                  "LongRunEmphasis"  0.179305
#    13.                 "ShortRunEmphasis"  0.138163
#    14.     "LongRunHighGrayLevelEmphasis"  0.126985
#    15. "RunLengthNonUniformityNormalized"  0.045880
#    16. "GrayLevelNonUniformityNormalized"  0.008865
#
#
#
# Loss: BINOMIAL_LOG_LIKELIHOOD
# Validation loss value: 2.0241e-06
# Number of trees per iteration: 1
# Node format: NOT_SET
# Number of trees: 300
# Total number of nodes: 6060
#
# Number of nodes by tree:
# Count: 300 Average: 20.2 StdDev: 3.02435
# Min: 11 Max: 27 Ignored: 0
# ----------------------------------------------
# [ 11, 12)   1   0.33%   0.33%
# [ 12, 13)   0   0.00%   0.33%
# [ 13, 14)  12   4.00%   4.33% #
# [ 14, 15)   0   0.00%   4.33%
# [ 15, 16)   8   2.67%   7.00% #
# [ 16, 17)   0   0.00%   7.00%
# [ 17, 18)  53  17.67%  24.67% ####
# [ 18, 19)   0   0.00%  24.67%
# [ 19, 20)  40  13.33%  38.00% ###
# [ 20, 21)   0   0.00%  38.00%
# [ 21, 22) 119  39.67%  77.67% ##########
# [ 22, 23)   0   0.00%  77.67%
# [ 23, 24)  40  13.33%  91.00% ###
# [ 24, 25)   0   0.00%  91.00%
# [ 25, 26)  18   6.00%  97.00% ##
# [ 26, 27)   0   0.00%  97.00%
# [ 27, 27]   9   3.00% 100.00% #
#
# Depth by leafs:
# Count: 3180 Average: 4.07704 StdDev: 1.23702
# Min: 1 Max: 5 Ignored: 0
# ----------------------------------------------
# [ 1, 2)  190   5.97%   5.97% #
# [ 2, 3)  215   6.76%  12.74% #
# [ 3, 4)  535  16.82%  29.56% ###
# [ 4, 5)  460  14.47%  44.03% ###
# [ 5, 5] 1780  55.97% 100.00% ##########
#
# Number of training obs by leaf:
# Count: 3180 Average: 43.2075 StdDev: 93.2938
# Min: 5 Max: 426 Ignored: 0
# ----------------------------------------------
# [   5,  26) 2618  82.33%  82.33% ##########
# [  26,  47)   48   1.51%  83.84%
# [  47,  68)   23   0.72%  84.56%
# [  68,  89)    1   0.03%  84.59%
# [  89, 110)   18   0.57%  85.16%
# [ 110, 131)    2   0.06%  85.22%
# [ 131, 152)   51   1.60%  86.82%
# [ 152, 173)  137   4.31%  91.13% #
# [ 173, 194)    3   0.09%  91.23%
# [ 194, 216)   24   0.75%  91.98%
# [ 216, 237)   49   1.54%  93.52%
# [ 237, 258)   77   2.42%  95.94%
# [ 258, 279)    1   0.03%  95.97%
# [ 279, 300)    0   0.00%  95.97%
# [ 300, 321)    0   0.00%  95.97%
# [ 321, 342)    1   0.03%  96.01%
# [ 342, 363)    0   0.00%  96.01%
# [ 363, 384)    3   0.09%  96.10%
# [ 384, 405)   75   2.36%  98.46%
# [ 405, 426]   49   1.54% 100.00%
#
# Attribute in nodes:
# 	711 : GrayLevelVariance [NUMERICAL]
# 	260 : ShortRunHighGrayLevelEmphasis [NUMERICAL]
# 	252 : RunEntropy [NUMERICAL]
# 	242 : LongRunLowGrayLevelEmphasis [NUMERICAL]
# 	228 : GrayLevelNonUniformityNormalized [NUMERICAL]
# 	213 : HighGrayLevelRunEmphasis [NUMERICAL]
# 	180 : ShortRunLowGrayLevelEmphasis [NUMERICAL]
# 	148 : GrayLevelNonUniformity [NUMERICAL]
# 	119 : RunVariance [NUMERICAL]
# 	114 : ShortRunEmphasis [NUMERICAL]
# 	97 : LowGrayLevelRunEmphasis [NUMERICAL]
# 	84 : LongRunHighGrayLevelEmphasis [NUMERICAL]
# 	74 : LongRunEmphasis [NUMERICAL]
# 	73 : RunLengthNonUniformityNormalized [NUMERICAL]
# 	43 : RunLengthNonUniformity [NUMERICAL]
# 	42 : RunPercentage [NUMERICAL]
#
# Attribute in nodes with depth <= 0:
# 	187 : GrayLevelVariance [NUMERICAL]
# 	28 : ShortRunHighGrayLevelEmphasis [NUMERICAL]
# 	22 : HighGrayLevelRunEmphasis [NUMERICAL]
# 	21 : ShortRunLowGrayLevelEmphasis [NUMERICAL]
# 	21 : LowGrayLevelRunEmphasis [NUMERICAL]
# 	17 : LongRunLowGrayLevelEmphasis [NUMERICAL]
# 	4 : RunEntropy [NUMERICAL]
#
# Attribute in nodes with depth <= 1:
# 	257 : GrayLevelVariance [NUMERICAL]
# 	102 : ShortRunLowGrayLevelEmphasis [NUMERICAL]
# 	84 : RunEntropy [NUMERICAL]
# 	74 : HighGrayLevelRunEmphasis [NUMERICAL]
# 	62 : LowGrayLevelRunEmphasis [NUMERICAL]
# 	50 : LongRunLowGrayLevelEmphasis [NUMERICAL]
# 	36 : ShortRunHighGrayLevelEmphasis [NUMERICAL]
# 	10 : RunPercentage [NUMERICAL]
# 	6 : RunVariance [NUMERICAL]
# 	6 : LongRunHighGrayLevelEmphasis [NUMERICAL]
# 	6 : GrayLevelNonUniformity [NUMERICAL]
# 	4 : ShortRunEmphasis [NUMERICAL]
# 	4 : RunLengthNonUniformity [NUMERICAL]
# 	3 : RunLengthNonUniformityNormalized [NUMERICAL]
# 	3 : LongRunEmphasis [NUMERICAL]
# 	3 : GrayLevelNonUniformityNormalized [NUMERICAL]
#
# Attribute in nodes with depth <= 2:
# 	475 : GrayLevelVariance [NUMERICAL]
# 	164 : RunEntropy [NUMERICAL]
# 	126 : LongRunLowGrayLevelEmphasis [NUMERICAL]
# 	114 : ShortRunLowGrayLevelEmphasis [NUMERICAL]
# 	98 : HighGrayLevelRunEmphasis [NUMERICAL]
# 	69 : ShortRunHighGrayLevelEmphasis [NUMERICAL]
# 	65 : LowGrayLevelRunEmphasis [NUMERICAL]
# 	52 : GrayLevelNonUniformity [NUMERICAL]
# 	39 : LongRunEmphasis [NUMERICAL]
# 	31 : RunVariance [NUMERICAL]
# 	28 : GrayLevelNonUniformityNormalized [NUMERICAL]
# 	15 : LongRunHighGrayLevelEmphasis [NUMERICAL]
# 	13 : ShortRunEmphasis [NUMERICAL]
# 	13 : RunPercentage [NUMERICAL]
# 	9 : RunLengthNonUniformity [NUMERICAL]
# 	4 : RunLengthNonUniformityNormalized [NUMERICAL]
#
# Attribute in nodes with depth <= 3:
# 	611 : GrayLevelVariance [NUMERICAL]
# 	188 : RunEntropy [NUMERICAL]
# 	181 : HighGrayLevelRunEmphasis [NUMERICAL]
# 	168 : LongRunLowGrayLevelEmphasis [NUMERICAL]
# 	161 : GrayLevelNonUniformityNormalized [NUMERICAL]
# 	156 : ShortRunHighGrayLevelEmphasis [NUMERICAL]
# 	138 : ShortRunLowGrayLevelEmphasis [NUMERICAL]
# 	75 : GrayLevelNonUniformity [NUMERICAL]
# 	72 : LowGrayLevelRunEmphasis [NUMERICAL]
# 	60 : LongRunEmphasis [NUMERICAL]
# 	46 : ShortRunEmphasis [NUMERICAL]
# 	38 : RunVariance [NUMERICAL]
# 	35 : LongRunHighGrayLevelEmphasis [NUMERICAL]
# 	22 : RunLengthNonUniformity [NUMERICAL]
# 	20 : RunPercentage [NUMERICAL]
# 	19 : RunLengthNonUniformityNormalized [NUMERICAL]
#
# Attribute in nodes with depth <= 5:
# 	711 : GrayLevelVariance [NUMERICAL]
# 	260 : ShortRunHighGrayLevelEmphasis [NUMERICAL]
# 	252 : RunEntropy [NUMERICAL]
# 	242 : LongRunLowGrayLevelEmphasis [NUMERICAL]
# 	228 : GrayLevelNonUniformityNormalized [NUMERICAL]
# 	213 : HighGrayLevelRunEmphasis [NUMERICAL]
# 	180 : ShortRunLowGrayLevelEmphasis [NUMERICAL]
# 	148 : GrayLevelNonUniformity [NUMERICAL]
# 	119 : RunVariance [NUMERICAL]
# 	114 : ShortRunEmphasis [NUMERICAL]
# 	97 : LowGrayLevelRunEmphasis [NUMERICAL]
# 	84 : LongRunHighGrayLevelEmphasis [NUMERICAL]
# 	74 : LongRunEmphasis [NUMERICAL]
# 	73 : RunLengthNonUniformityNormalized [NUMERICAL]
# 	43 : RunLengthNonUniformity [NUMERICAL]
# 	42 : RunPercentage [NUMERICAL]
#
# Condition type in nodes:
# 	2880 : HigherCondition
# Condition type in nodes with depth <= 0:
# 	300 : HigherCondition
# Condition type in nodes with depth <= 1:
# 	710 : HigherCondition
# Condition type in nodes with depth <= 2:
# 	1315 : HigherCondition
# Condition type in nodes with depth <= 3:
# 	1990 : HigherCondition
# Condition type in nodes with depth <= 5:
# 	2880 : HigherCondition
#
# Training logs:
# Number of iteration to final model: 300
# 	Iter:1 train-loss:1.197316 valid-loss:1.285290  train-accuracy:0.994512 valid-accuracy:1.000000
# 	Iter:2 train-loss:1.045128 valid-loss:1.113962  train-accuracy:0.994512 valid-accuracy:1.000000
# 	Iter:3 train-loss:0.918370 valid-loss:0.972265  train-accuracy:0.994512 valid-accuracy:1.000000
# 	Iter:4 train-loss:0.811347 valid-loss:0.853238  train-accuracy:0.994512 valid-accuracy:1.000000
# 	Iter:5 train-loss:0.720028 valid-loss:0.752058  train-accuracy:0.994512 valid-accuracy:1.000000
# 	Iter:6 train-loss:0.641460 valid-loss:0.665240  train-accuracy:0.994512 valid-accuracy:1.000000
# 	Iter:16 train-loss:0.219019 valid-loss:0.219255  train-accuracy:0.997805 valid-accuracy:1.000000
# 	Iter:26 train-loss:0.083225 valid-loss:0.084528  train-accuracy:1.000000 valid-accuracy:1.000000
# 	Iter:36 train-loss:0.031978 valid-loss:0.031708  train-accuracy:1.000000 valid-accuracy:1.000000
# 	Iter:46 train-loss:0.012978 valid-loss:0.012513  train-accuracy:1.000000 valid-accuracy:1.000000
# 	Iter:56 train-loss:0.005313 valid-loss:0.005156  train-accuracy:1.000000 valid-accuracy:1.000000
# 	Iter:66 train-loss:0.002177 valid-loss:0.002147  train-accuracy:1.000000 valid-accuracy:1.000000
# 	Iter:76 train-loss:0.000809 valid-loss:0.000788  train-accuracy:1.000000 valid-accuracy:1.000000
# 	Iter:86 train-loss:0.000311 valid-loss:0.000290  train-accuracy:1.000000 valid-accuracy:1.000000
# 	Iter:96 train-loss:0.000133 valid-loss:0.000111  train-accuracy:1.000000 valid-accuracy:1.000000
# 	Iter:106 train-loss:0.000058 valid-loss:0.000048  train-accuracy:1.000000 valid-accuracy:1.000000
# 	Iter:116 train-loss:0.000028 valid-loss:0.000024  train-accuracy:1.000000 valid-accuracy:1.000000
# 	Iter:126 train-loss:0.000016 valid-loss:0.000014  train-accuracy:1.000000 valid-accuracy:1.000000
# 	Iter:136 train-loss:0.000012 valid-loss:0.000011  train-accuracy:1.000000 valid-accuracy:1.000000
# 	Iter:146 train-loss:0.000009 valid-loss:0.000009  train-accuracy:1.000000 valid-accuracy:1.000000
# 	Iter:156 train-loss:0.000008 valid-loss:0.000007  train-accuracy:1.000000 valid-accuracy:1.000000
# 	Iter:166 train-loss:0.000007 valid-loss:0.000006  train-accuracy:1.000000 valid-accuracy:1.000000
# 	Iter:176 train-loss:0.000006 valid-loss:0.000005  train-accuracy:1.000000 valid-accuracy:1.000000
# 	Iter:186 train-loss:0.000005 valid-loss:0.000005  train-accuracy:1.000000 valid-accuracy:1.000000
# 	Iter:196 train-loss:0.000005 valid-loss:0.000004  train-accuracy:1.000000 valid-accuracy:1.000000
# 	Iter:206 train-loss:0.000004 valid-loss:0.000004  train-accuracy:1.000000 valid-accuracy:1.000000
# 	Iter:216 train-loss:0.000004 valid-loss:0.000004  train-accuracy:1.000000 valid-accuracy:1.000000
# 	Iter:226 train-loss:0.000004 valid-loss:0.000003  train-accuracy:1.000000 valid-accuracy:1.000000
# 	Iter:236 train-loss:0.000003 valid-loss:0.000003  train-accuracy:1.000000 valid-accuracy:1.000000
# 	Iter:246 train-loss:0.000003 valid-loss:0.000003  train-accuracy:1.000000 valid-accuracy:1.000000
# 	Iter:256 train-loss:0.000003 valid-loss:0.000003  train-accuracy:1.000000 valid-accuracy:1.000000
# 	Iter:266 train-loss:0.000003 valid-loss:0.000003  train-accuracy:1.000000 valid-accuracy:1.000000
# 	Iter:276 train-loss:0.000002 valid-loss:0.000002  train-accuracy:1.000000 valid-accuracy:1.000000
# 	Iter:286 train-loss:0.000002 valid-loss:0.000002  train-accuracy:1.000000 valid-accuracy:1.000000
# 	Iter:296 train-loss:0.000002 valid-loss:0.000002  train-accuracy:1.000000 valid-accuracy:1.000000

# %%
# Model features
model.make_inspector().features()
# Out:
# ["GrayLevelNonUniformity" (1; #0),
#  "GrayLevelNonUniformityNormalized" (1; #1),
#  "GrayLevelVariance" (1; #2),
#  "HighGrayLevelRunEmphasis" (1; #3),
#  "LongRunEmphasis" (1; #4),
#  "LongRunHighGrayLevelEmphasis" (1; #5),
#  "LongRunLowGrayLevelEmphasis" (1; #6),
#  "LowGrayLevelRunEmphasis" (1; #7),
#  "RunEntropy" (1; #8),
#  "RunLengthNonUniformity" (1; #9),
#  "RunLengthNonUniformityNormalized" (1; #10),
#  "RunPercentage" (1; #11),
#  "RunVariance" (1; #12),
#  "ShortRunEmphasis" (1; #13),
#  "ShortRunHighGrayLevelEmphasis" (1; #14),
#  "ShortRunLowGrayLevelEmphasis" (1; #15)]

# %%
# Feature importance
model.make_inspector().variable_importances()
# Out:
# {'INV_MEAN_MIN_DEPTH': [("GrayLevelVariance" (1; #2), 0.5383397274745512),
#   ("ShortRunLowGrayLevelEmphasis" (1; #15), 0.2572701159568629),
#   ("HighGrayLevelRunEmphasis" (1; #3), 0.24894768034556883),
#   ("LongRunLowGrayLevelEmphasis" (1; #6), 0.23570600640205094),
#   ("ShortRunHighGrayLevelEmphasis" (1; #14), 0.23237488723209404),
#   ("LowGrayLevelRunEmphasis" (1; #7), 0.23106541224830562),
#   ("RunEntropy" (1; #8), 0.22953411617047598),
#   ("GrayLevelNonUniformityNormalized" (1; #1), 0.21626119772528002),
#   ("GrayLevelNonUniformity" (1; #0), 0.2080473835671569),
#   ("RunVariance" (1; #12), 0.20485590701206324),
#   ("LongRunEmphasis" (1; #4), 0.20475101057032885),
#   ("ShortRunEmphasis" (1; #13), 0.20289749171776397),
#   ("LongRunHighGrayLevelEmphasis" (1; #5), 0.20276091846202277),
#   ("RunPercentage" (1; #11), 0.2007871055868437),
#   ("RunLengthNonUniformityNormalized" (1; #10), 0.20056800737985192),
#   ("RunLengthNonUniformity" (1; #9), 0.20018784933898165)],
#  'SUM_SCORE': [("HighGrayLevelRunEmphasis" (1; #3), 476.4878826964354),
#   ("RunEntropy" (1; #8), 69.22849973614011),
#   ("ShortRunHighGrayLevelEmphasis" (1; #14), 68.11773555157046),
#   ("GrayLevelVariance" (1; #2), 11.39241619482556),
#   ("LongRunLowGrayLevelEmphasis" (1; #6), 4.584736936782698),
#   ("RunPercentage" (1; #11), 3.8846307393975437),
#   ("GrayLevelNonUniformity" (1; #0), 3.631541866771097),
#   ("ShortRunLowGrayLevelEmphasis" (1; #15), 3.6139288294113916),
#   ("LowGrayLevelRunEmphasis" (1; #7), 1.0042927414865281),
#   ("RunLengthNonUniformity" (1; #9), 0.5811571337921345),
#   ("RunVariance" (1; #12), 0.2135005202244183),
#   ("LongRunEmphasis" (1; #4), 0.17930546738746264),
#   ("ShortRunEmphasis" (1; #13), 0.13816256773490487),
#   ("LongRunHighGrayLevelEmphasis" (1; #5), 0.12698502368351125),
#   ("RunLengthNonUniformityNormalized" (1; #10), 0.045879557123544676),
#   ("GrayLevelNonUniformityNormalized" (1; #1), 0.008865274106724448)],
#  'NUM_AS_ROOT': [("GrayLevelVariance" (1; #2), 187.0),
#   ("ShortRunHighGrayLevelEmphasis" (1; #14), 28.0),
#   ("HighGrayLevelRunEmphasis" (1; #3), 22.0),
#   ("LowGrayLevelRunEmphasis" (1; #7), 21.0),
#   ("ShortRunLowGrayLevelEmphasis" (1; #15), 21.0),
#   ("LongRunLowGrayLevelEmphasis" (1; #6), 17.0),
#   ("RunEntropy" (1; #8), 4.0)],
#  'NUM_NODES': [("GrayLevelVariance" (1; #2), 711.0),
#   ("ShortRunHighGrayLevelEmphasis" (1; #14), 260.0),
#   ("RunEntropy" (1; #8), 252.0),
#   ("LongRunLowGrayLevelEmphasis" (1; #6), 242.0),
#   ("GrayLevelNonUniformityNormalized" (1; #1), 228.0),
#   ("HighGrayLevelRunEmphasis" (1; #3), 213.0),
#   ("ShortRunLowGrayLevelEmphasis" (1; #15), 180.0),
#   ("GrayLevelNonUniformity" (1; #0), 148.0),
#   ("RunVariance" (1; #12), 119.0),
#   ("ShortRunEmphasis" (1; #13), 114.0),
#   ("LowGrayLevelRunEmphasis" (1; #7), 97.0),
#   ("LongRunHighGrayLevelEmphasis" (1; #5), 84.0),
#   ("LongRunEmphasis" (1; #4), 74.0),
#   ("RunLengthNonUniformityNormalized" (1; #10), 73.0),
#   ("RunLengthNonUniformity" (1; #9), 43.0),
#   ("RunPercentage" (1; #11), 42.0)]}

# %%
# Model self evaluation
model.make_inspector().evaluation()
# Out:
# Evaluation(num_examples=None, accuracy=1.0, loss=2.024101604547468e-06, rmse=None, ndcg=None, aucs=None, auuc=None, qini=None)

# %%
logs = model.make_inspector().training_logs()

plt.figure(figsize=(12, 4))
plt.subplot(1, 2, 1)
plt.plot([log.num_trees for log in logs], [log.evaluation.accuracy for log in logs])
plt.xlabel("Number of trees")
plt.ylabel("Accuracy (out-of-bag)")
plt.subplot(1, 2, 2)
plt.plot([log.num_trees for log in logs], [log.evaluation.loss for log in logs])
plt.xlabel("Number of trees")
plt.ylabel("Logloss (out-of-bag)")
plt.show()

# %% [markdown]
# Calculate the score of our hold-out validation dataset

# %%
predictions = model.predict(val_ds)
y_true      = validation_data["label"]

from sklearn.metrics import roc_auc_score
ROC_AUC = roc_auc_score(y_true, predictions)
print("The ROC AUC score is %.5f" % ROC_AUC )
# Out:
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 62ms/step
# The ROC AUC score is 0.99034

# %%
# Compute binary classification metrics with sklearn
import numpy as np
from sklearn.metrics import (
    accuracy_score,
    precision_score,
    recall_score,
    f1_score,
    roc_auc_score,
    average_precision_score,
    confusion_matrix,
    classification_report,
    matthews_corrcoef,
    log_loss,
    brier_score_loss,
)

# Get predictions (probabilities or class labels)
preds = model.predict(test_ds)
# If model outputs probabilities, convert to labels by threshold 0.5
if preds.ndim == 2:
    # For TFDF classification, preds may be class probabilities with shape (N, 2)
    if preds.shape[1] == 2:
        pos_probs = preds[:, 1]
    else:
        # If single-probability column (positive class)
        pos_probs = preds[:, -1]
    y_pred = (pos_probs >= 0.5).astype(int)
else:
    # Already class labels
    y_pred = preds.astype(int)
    pos_probs = None

# Ground truth labels (must be 0/1 integers)
y_true = test_data["label"].astype(int).to_numpy()

# Core metrics
metrics = {}
metrics["accuracy"] = accuracy_score(y_true, y_pred)
metrics["precision"] = precision_score(y_true, y_pred, zero_division=0)
metrics["recall"] = recall_score(y_true, y_pred, zero_division=0)
metrics["f1"] = f1_score(y_true, y_pred, zero_division=0)
metrics["mcc"] = matthews_corrcoef(y_true, y_pred)

# Probabilistic metrics (only if we have probabilities)
if pos_probs is not None:
    metrics["roc_auc"] = roc_auc_score(y_true, pos_probs)
    metrics["pr_auc"] = average_precision_score(y_true, pos_probs)
    metrics["log_loss"] = log_loss(y_true, pos_probs, labels=[0,1])
    metrics["brier_score"] = brier_score_loss(y_true, pos_probs)

# Confusion matrix and detailed report
cm = confusion_matrix(y_true, y_pred, labels=[0,1])
report = classification_report(y_true, y_pred, digits=4)

print("Sklearn binary metrics:")
for k, v in metrics.items():
    print(f"{k}: {v:.4f}")
print("\nConfusion matrix:\n", cm)
print("\nClassification report:\n", report)
# Out:
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 65ms/step
# Sklearn binary metrics:
# accuracy: 0.9726
# precision: 0.8750
# recall: 0.7000
# f1: 0.7778
# mcc: 0.7688
# roc_auc: 0.9945
# pr_auc: 0.8663
# log_loss: 0.2730
# brier_score: 0.0274
#
# Confusion matrix:
#  [[135   1]
#  [  3   7]]
#
# Classification report:
#                precision    recall  f1-score   support
#
#            0     0.9783    0.9926    0.9854       136
#            1     0.8750    0.7000    0.7778        10
#
#     accuracy                         0.9726       146
#    macro avg     0.9266    0.8463    0.8816       146
# weighted avg     0.9712    0.9726    0.9712       146
