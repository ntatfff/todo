# %%
# Import packages and modules
import numpy  as np
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow_decision_forests as tfdf

from sklearn.model_selection import train_test_split
# Out:
# 2026-08-10 17:16:05.126607: I tensorflow/core/util/port.cc:113] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2026-08-10 17:16:05.480001: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2026-08-10 17:16:10.225216: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
# Check the version of TensorFlow Decision Forests
print("Found TensorFlow Decision Forests v" + tfdf.__version__)
# Out:
# Found TensorFlow Decision Forests v1.9.1

# %%
datasetPath = 'dataset/firstorder/kernel5-radius5/dataset.csv'

# %%
# Parameters
datasetPath = "dataset/glrlm/kernel6-radius6/dataset.1p.csv"

# %%
# train/validation/test = 70/10/20
dataset = pd.read_csv(datasetPath)

train_data, temp_data = train_test_split(dataset, test_size=0.3, random_state=42)
validation_data, test_data = train_test_split(temp_data, test_size=2/3, random_state=42)

# %%
from sklearn.utils.class_weight import compute_class_weight

# tinh class weight tren tap train
classes = np.array([0, 1])
weights = compute_class_weight(class_weight="balanced", classes=classes, y=train_data["label"])
class_weight = {0: weights[0], 1: weights[1]}

# gan sample_weight cho tung dong
train_data["sample_weight"] = train_data["label"].map(class_weight)
validation_data["sample_weight"] = validation_data["label"].map(class_weight)
test_data["sample_weight"] = test_data["label"].map(class_weight)

# Convert the dataset into a TensorFlow dataset.
train_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    train_data, label="label", weight="sample_weight"
)         
val_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    validation_data, label="label", weight="sample_weight"
)
test_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    test_data, label="label", weight="sample_weight"
)
# Out:
# 2026-08-10 17:16:24.162379: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:984] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2026-08-10 17:16:24.163838: W tensorflow/core/common_runtime/gpu/gpu_device.cc:2251] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...

# %%
import keras

# %%
# %%time

# Train a Gradient Boosted Trees model.
model = tfdf.keras.GradientBoostedTreesModel()

# Add evaluation metrics
model.compile(
    metrics=["accuracy"]
)
model.fit(x=train_ds)

# # Train a Gradient Boosted Trees model.
# model = tfdf.keras.GradientBoostedTreesModel(num_trees=1500)
# model.fit(train_ds)
# Out:
# Use /tmp/tmpk9kllvns as temporary training directory
# Reading training dataset...
# [WARNING 26-08-10 17:16:24.3379 UTC gradient_boosted_trees.cc:1840] "goss_alpha" set but "sampling_method" not equal to "GOSS".
# [WARNING 26-08-10 17:16:24.3381 UTC gradient_boosted_trees.cc:1851] "goss_beta" set but "sampling_method" not equal to "GOSS".
# [WARNING 26-08-10 17:16:24.3381 UTC gradient_boosted_trees.cc:1865] "selective_gradient_boosting_ratio" set but "sampling_method" not equal to "SELGB".
# Training dataset read in 0:00:02.514808. Found 777 examples.
# Training model...
# Model trained in 0:00:01.384798
# Compiling model...
# [INFO 26-08-10 17:16:28.2572 UTC kernel.cc:1233] Loading model from path /tmp/tmpk9kllvns/model/ with prefix f15beda4033f4c93
# [INFO 26-08-10 17:16:28.2656 UTC quick_scorer_extended.cc:911] The binary was compiled without AVX2 support, but your CPU supports it. Enable it for faster model inference.
# [INFO 26-08-10 17:16:28.2661 UTC abstract_model.cc:1362] Engine "GradientBoostedTreesQuickScorerExtended" built
# [INFO 26-08-10 17:16:28.2661 UTC kernel.cc:1061] Use fast generic engine
# Model compiled.
# CPU times: user 7.22 s, sys: 1.86 s, total: 9.08 s
# Wall time: 8.82 s

# %%
# Evaluate the model
evaluate = model.evaluate(val_ds, return_dict=True)
print()

for name, value in evaluate.items():
    print(f"{name}: {value:.4f}")
# Out:
# WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 1/1 [==============================] - ETA: 0s - loss: 0.0000e+00 - accuracy: 1.0000
# 1/1 [==============================] - 3s 3s/step - loss: 0.0000e+00 - accuracy: 1.0000
# loss: 0.0000
# accuracy: 1.0000

# %%
# Model Summary
model.summary()
# Out:
# Model: "gradient_boosted_trees_model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
# =================================================================
# Total params: 1 (1.00 Byte)
# Trainable params: 0 (0.00 Byte)
# Non-trainable params: 1 (1.00 Byte)
# _________________________________________________________________
# Type: "GRADIENT_BOOSTED_TREES"
# Task: CLASSIFICATION
# Label: "__LABEL"
#
# Input Features (34):
# 	10Percentile
# 	90Percentile
# 	Energy
# 	Entropy
# 	GrayLevelNonUniformity
# 	GrayLevelNonUniformityNormalized
# 	GrayLevelVariance
# 	HighGrayLevelRunEmphasis
# 	InterquartileRange
# 	Kurtosis
# 	LongRunEmphasis
# 	LongRunHighGrayLevelEmphasis
# 	LongRunLowGrayLevelEmphasis
# 	LowGrayLevelRunEmphasis
# 	Maximum
# 	Mean
# 	MeanAbsoluteDeviation
# 	Median
# 	Minimum
# 	Range
# 	RobustMeanAbsoluteDeviation
# 	RootMeanSquared
# 	RunEntropy
# 	RunLengthNonUniformity
# 	RunLengthNonUniformityNormalized
# 	RunPercentage
# 	RunVariance
# 	ShortRunEmphasis
# 	ShortRunHighGrayLevelEmphasis
# 	ShortRunLowGrayLevelEmphasis
# 	Skewness
# 	TotalEnergy
# 	Uniformity
# 	Variance
#
# Trained with weights
#
# Variable Importance: INV_MEAN_MIN_DEPTH:
#     1.                      "RunVariance"  0.282531 ################
#     2.      "LongRunLowGrayLevelEmphasis"  0.280930 ###############
#     3.                           "Energy"  0.262933 ###########
#     4.                  "RootMeanSquared"  0.253900 #########
#     5.                 "ShortRunEmphasis"  0.247892 ########
#     6.                      "TotalEnergy"  0.247195 ########
#     7. "RunLengthNonUniformityNormalized"  0.245588 ########
#     8. "GrayLevelNonUniformityNormalized"  0.238280 ######
#     9.                    "RunPercentage"  0.218822 ##
#    10.                         "Kurtosis"  0.214483 #
#    11.          "LowGrayLevelRunEmphasis"  0.214149 #
#    12.     "ShortRunLowGrayLevelEmphasis"  0.214100 #
#    13.     "LongRunHighGrayLevelEmphasis"  0.212402 #
#    14.           "RunLengthNonUniformity"  0.211831 #
#    15.                     "10Percentile"  0.210769
#    16.                  "LongRunEmphasis"  0.210399
#    17.                            "Range"  0.210191
#    18.                "GrayLevelVariance"  0.209030
#    19.           "GrayLevelNonUniformity"  0.208505
#    20.               "InterquartileRange"  0.208413
#    21.                          "Entropy"  0.208343
#    22.         "HighGrayLevelRunEmphasis"  0.208339
#    23.    "ShortRunHighGrayLevelEmphasis"  0.208306
#    24.                          "Maximum"  0.208274
#    25.                     "90Percentile"  0.208240
#    26.                       "Uniformity"  0.208027
#    27.      "RobustMeanAbsoluteDeviation"  0.207860
#    28.                         "Skewness"  0.207561
#    29.            "MeanAbsoluteDeviation"  0.207534
#    30.                             "Mean"  0.207462
#    31.                         "Variance"  0.207254
#    32.                       "RunEntropy"  0.207239
#    33.                           "Median"  0.207222
#    34.                          "Minimum"  0.207081
#
# Variable Importance: NUM_AS_ROOT:
#     1.     "RunVariance" 110.000000 ################
#     2.          "Energy" 73.000000 ##########
#     3. "RootMeanSquared" 60.000000 ########
#     4.     "TotalEnergy" 53.000000 #######
#     5.        "Kurtosis"  2.000000
#
# Variable Importance: NUM_NODES:
#     1. "GrayLevelNonUniformityNormalized" 344.000000 ################
#     2.      "LongRunLowGrayLevelEmphasis" 330.000000 ###############
#     3.                      "RunVariance" 252.000000 ###########
#     4. "RunLengthNonUniformityNormalized" 207.000000 #########
#     5.                    "RunPercentage" 196.000000 ########
#     6.                 "ShortRunEmphasis" 196.000000 ########
#     7.                         "Kurtosis" 141.000000 ######
#     8.                  "LongRunEmphasis" 138.000000 #####
#     9.     "LongRunHighGrayLevelEmphasis" 123.000000 #####
#    10.                     "10Percentile" 112.000000 ####
#    11.     "ShortRunLowGrayLevelEmphasis" 104.000000 ####
#    12.                            "Range" 100.000000 ####
#    13.           "RunLengthNonUniformity" 99.000000 ####
#    14.                           "Energy" 93.000000 ###
#    15.                "GrayLevelVariance" 92.000000 ###
#    16.                  "RootMeanSquared" 87.000000 ###
#    17.                      "TotalEnergy" 86.000000 ###
#    18.          "LowGrayLevelRunEmphasis" 75.000000 ##
#    19.           "GrayLevelNonUniformity" 64.000000 ##
#    20.         "HighGrayLevelRunEmphasis" 59.000000 ##
#    21.               "InterquartileRange" 58.000000 ##
#    22.    "ShortRunHighGrayLevelEmphasis" 45.000000 #
#    23.                          "Entropy" 43.000000 #
#    24.                          "Maximum" 40.000000 #
#    25.                         "Skewness" 38.000000 #
#    26.                     "90Percentile" 36.000000
#    27.            "MeanAbsoluteDeviation" 35.000000
#    28.      "RobustMeanAbsoluteDeviation" 31.000000
#    29.                       "Uniformity" 29.000000
#    30.                         "Variance" 26.000000
#    31.                       "RunEntropy" 22.000000
#    32.                             "Mean" 18.000000
#    33.                           "Median" 17.000000
#    34.                          "Minimum" 17.000000
#
# Variable Importance: SUM_SCORE:
#     1.                      "RunVariance" 664.198614 ################
#     2.      "LongRunLowGrayLevelEmphasis" 130.665955 ###
#     3.                    "RunPercentage" 81.102269 #
#     4.          "LowGrayLevelRunEmphasis" 76.042801 #
#     5.     "ShortRunLowGrayLevelEmphasis"  0.462280
#     6.                           "Energy"  0.000001
#     7.                  "RootMeanSquared"  0.000001
#     8.                      "TotalEnergy"  0.000000
#     9. "RunLengthNonUniformityNormalized"  0.000000
#    10.                 "ShortRunEmphasis"  0.000000
#    11.                         "Kurtosis"  0.000000
#    12. "GrayLevelNonUniformityNormalized"  0.000000
#    13.           "RunLengthNonUniformity"  0.000000
#    14.                     "10Percentile"  0.000000
#    15.           "GrayLevelNonUniformity"  0.000000
#    16.     "LongRunHighGrayLevelEmphasis"  0.000000
#    17.                  "LongRunEmphasis"  0.000000
#    18.                             "Mean"  0.000000
#    19.         "HighGrayLevelRunEmphasis"  0.000000
#    20.                            "Range"  0.000000
#    21.               "InterquartileRange"  0.000000
#    22.                         "Variance"  0.000000
#    23.                "GrayLevelVariance"  0.000000
#    24.                          "Entropy"  0.000000
#    25.                          "Maximum"  0.000000
#    26.                     "90Percentile"  0.000000
#    27.            "MeanAbsoluteDeviation"  0.000000
#    28.    "ShortRunHighGrayLevelEmphasis"  0.000000
#    29.      "RobustMeanAbsoluteDeviation"  0.000000
#    30.                       "RunEntropy"  0.000000
#    31.                         "Skewness"  0.000000
#    32.                          "Minimum"  0.000000
#    33.                       "Uniformity"  0.000000
#    34.                           "Median"  0.000000
#
#
#
# Loss: BINOMIAL_LOG_LIKELIHOOD
# Validation loss value: 1.53492e-06
# Number of trees per iteration: 1
# Node format: NOT_SET
# Number of trees: 298
# Total number of nodes: 7004
#
# Number of nodes by tree:
# Count: 298 Average: 23.5034 StdDev: 7.18885
# Min: 5 Max: 41 Ignored: 0
# ----------------------------------------------
# [  5,  6)   1   0.34%   0.34%
# [  6,  8)   0   0.00%   0.34%
# [  8, 10)   6   2.01%   2.35%
# [ 10, 12)  21   7.05%   9.40% ##
# [ 12, 14)  15   5.03%  14.43% #
# [ 14, 16)  21   7.05%  21.48% ##
# [ 16, 17)   0   0.00%  21.48%
# [ 17, 19)  11   3.69%  25.17% #
# [ 19, 21)   5   1.68%  26.85%
# [ 21, 23)   3   1.01%  27.85%
# [ 23, 25)   0   0.00%  27.85%
# [ 25, 27) 137  45.97%  73.83% ##########
# [ 27, 29)  40  13.42%  87.25% ###
# [ 29, 30)   2   0.67%  87.92%
# [ 30, 32)   1   0.34%  88.26%
# [ 32, 34)   5   1.68%  89.93%
# [ 34, 36)  20   6.71%  96.64% #
# [ 36, 38)   2   0.67%  97.32%
# [ 38, 40)   1   0.34%  97.65%
# [ 40, 41]   7   2.35% 100.00% #
#
# Depth by leafs:
# Count: 3651 Average: 3.99617 StdDev: 1.01102
# Min: 1 Max: 5 Ignored: 0
# ----------------------------------------------
# [ 1, 2)    9   0.25%   0.25%
# [ 2, 3)  302   8.27%   8.52% ##
# [ 3, 4)  913  25.01%  33.53% ######
# [ 4, 5)  897  24.57%  58.09% ######
# [ 5, 5] 1530  41.91% 100.00% ##########
#
# Number of training obs by leaf:
# Count: 3651 Average: 57.8696 StdDev: 116.921
# Min: 5 Max: 571 Ignored: 0
# ----------------------------------------------
# [   5,  33) 2793  76.50%  76.50% ##########
# [  33,  61)  167   4.57%  81.07% #
# [  61,  90)  126   3.45%  84.52%
# [  90, 118)   20   0.55%  85.07%
# [ 118, 146)   27   0.74%  85.81%
# [ 146, 175)   30   0.82%  86.63%
# [ 175, 203)   11   0.30%  86.94%
# [ 203, 231)   73   2.00%  88.93%
# [ 231, 260)   92   2.52%  91.45%
# [ 260, 288)   76   2.08%  93.54%
# [ 288, 316)   25   0.68%  94.22%
# [ 316, 345)   39   1.07%  95.29%
# [ 345, 373)    5   0.14%  95.43%
# [ 373, 401)   61   1.67%  97.10%
# [ 401, 430)   17   0.47%  97.56%
# [ 430, 458)    4   0.11%  97.67%
# [ 458, 486)   19   0.52%  98.19%
# [ 486, 515)   12   0.33%  98.52%
# [ 515, 543)    0   0.00%  98.52%
# [ 543, 571]   54   1.48% 100.00%
#
# Attribute in nodes:
# 	344 : GrayLevelNonUniformityNormalized [NUMERICAL]
# 	330 : LongRunLowGrayLevelEmphasis [NUMERICAL]
# 	252 : RunVariance [NUMERICAL]
# 	207 : RunLengthNonUniformityNormalized [NUMERICAL]
# 	196 : ShortRunEmphasis [NUMERICAL]
# 	196 : RunPercentage [NUMERICAL]
# 	141 : Kurtosis [NUMERICAL]
# 	138 : LongRunEmphasis [NUMERICAL]
# 	123 : LongRunHighGrayLevelEmphasis [NUMERICAL]
# 	112 : 10Percentile [NUMERICAL]
# 	104 : ShortRunLowGrayLevelEmphasis [NUMERICAL]
# 	100 : Range [NUMERICAL]
# 	99 : RunLengthNonUniformity [NUMERICAL]
# 	93 : Energy [NUMERICAL]
# 	92 : GrayLevelVariance [NUMERICAL]
# 	87 : RootMeanSquared [NUMERICAL]
# 	86 : TotalEnergy [NUMERICAL]
# 	75 : LowGrayLevelRunEmphasis [NUMERICAL]
# 	64 : GrayLevelNonUniformity [NUMERICAL]
# 	59 : HighGrayLevelRunEmphasis [NUMERICAL]
# 	58 : InterquartileRange [NUMERICAL]
# 	45 : ShortRunHighGrayLevelEmphasis [NUMERICAL]
# 	43 : Entropy [NUMERICAL]
# 	40 : Maximum [NUMERICAL]
# 	38 : Skewness [NUMERICAL]
# 	36 : 90Percentile [NUMERICAL]
# 	35 : MeanAbsoluteDeviation [NUMERICAL]
# 	31 : RobustMeanAbsoluteDeviation [NUMERICAL]
# 	29 : Uniformity [NUMERICAL]
# 	26 : Variance [NUMERICAL]
# 	22 : RunEntropy [NUMERICAL]
# 	18 : Mean [NUMERICAL]
# 	17 : Minimum [NUMERICAL]
# 	17 : Median [NUMERICAL]
#
# Attribute in nodes with depth <= 0:
# 	110 : RunVariance [NUMERICAL]
# 	73 : Energy [NUMERICAL]
# 	60 : RootMeanSquared [NUMERICAL]
# 	53 : TotalEnergy [NUMERICAL]
# 	2 : Kurtosis [NUMERICAL]
#
# Attribute in nodes with depth <= 1:
# 	136 : RunVariance [NUMERICAL]
# 	101 : LongRunLowGrayLevelEmphasis [NUMERICAL]
# 	77 : Energy [NUMERICAL]
# 	73 : Kurtosis [NUMERICAL]
# 	70 : ShortRunEmphasis [NUMERICAL]
# 	68 : RootMeanSquared [NUMERICAL]
# 	67 : RunLengthNonUniformityNormalized [NUMERICAL]
# 	58 : TotalEnergy [NUMERICAL]
# 	29 : RunPercentage [NUMERICAL]
# 	29 : LowGrayLevelRunEmphasis [NUMERICAL]
# 	21 : ShortRunLowGrayLevelEmphasis [NUMERICAL]
# 	17 : Entropy [NUMERICAL]
# 	17 : 90Percentile [NUMERICAL]
# 	15 : Maximum [NUMERICAL]
# 	14 : Uniformity [NUMERICAL]
# 	13 : MeanAbsoluteDeviation [NUMERICAL]
# 	12 : InterquartileRange [NUMERICAL]
# 	12 : 10Percentile [NUMERICAL]
# 	11 : RobustMeanAbsoluteDeviation [NUMERICAL]
# 	10 : GrayLevelVariance [NUMERICAL]
# 	6 : LongRunHighGrayLevelEmphasis [NUMERICAL]
# 	6 : GrayLevelNonUniformityNormalized [NUMERICAL]
# 	5 : LongRunEmphasis [NUMERICAL]
# 	5 : GrayLevelNonUniformity [NUMERICAL]
# 	4 : ShortRunHighGrayLevelEmphasis [NUMERICAL]
# 	4 : RunEntropy [NUMERICAL]
# 	3 : RunLengthNonUniformity [NUMERICAL]
# 	1 : Mean [NUMERICAL]
# 	1 : HighGrayLevelRunEmphasis [NUMERICAL]
#
# Attribute in nodes with depth <= 2:
# 	248 : LongRunLowGrayLevelEmphasis [NUMERICAL]
# 	151 : RunVariance [NUMERICAL]
# 	134 : ShortRunEmphasis [NUMERICAL]
# 	120 : RunLengthNonUniformityNormalized [NUMERICAL]
# 	89 : Kurtosis [NUMERICAL]
# 	89 : Energy [NUMERICAL]
# 	83 : RootMeanSquared [NUMERICAL]
# 	81 : GrayLevelNonUniformityNormalized [NUMERICAL]
# 	80 : TotalEnergy [NUMERICAL]
# 	70 : RunPercentage [NUMERICAL]
# 	70 : 10Percentile [NUMERICAL]
# 	57 : RunLengthNonUniformity [NUMERICAL]
# 	45 : LowGrayLevelRunEmphasis [NUMERICAL]
# 	42 : ShortRunLowGrayLevelEmphasis [NUMERICAL]
# 	32 : Entropy [NUMERICAL]
# 	31 : InterquartileRange [NUMERICAL]
# 	30 : LongRunEmphasis [NUMERICAL]
# 	30 : 90Percentile [NUMERICAL]
# 	29 : Range [NUMERICAL]
# 	27 : Skewness [NUMERICAL]
# 	27 : RobustMeanAbsoluteDeviation [NUMERICAL]
# 	27 : Maximum [NUMERICAL]
# 	25 : MeanAbsoluteDeviation [NUMERICAL]
# 	20 : Uniformity [NUMERICAL]
# 	16 : LongRunHighGrayLevelEmphasis [NUMERICAL]
# 	16 : GrayLevelVariance [NUMERICAL]
# 	14 : ShortRunHighGrayLevelEmphasis [NUMERICAL]
# 	14 : Median [NUMERICAL]
# 	13 : Variance [NUMERICAL]
# 	10 : RunEntropy [NUMERICAL]
# 	10 : Minimum [NUMERICAL]
# 	9 : Mean [NUMERICAL]
# 	9 : HighGrayLevelRunEmphasis [NUMERICAL]
# 	9 : GrayLevelNonUniformity [NUMERICAL]
#
# Attribute in nodes with depth <= 3:
# 	305 : GrayLevelNonUniformityNormalized [NUMERICAL]
# 	269 : LongRunLowGrayLevelEmphasis [NUMERICAL]
# 	178 : RunVariance [NUMERICAL]
# 	165 : ShortRunEmphasis [NUMERICAL]
# 	155 : RunLengthNonUniformityNormalized [NUMERICAL]
# 	113 : Kurtosis [NUMERICAL]
# 	104 : RunPercentage [NUMERICAL]
# 	100 : 10Percentile [NUMERICAL]
# 	98 : LongRunHighGrayLevelEmphasis [NUMERICAL]
# 	97 : ShortRunLowGrayLevelEmphasis [NUMERICAL]
# 	92 : RunLengthNonUniformity [NUMERICAL]
# 	92 : Energy [NUMERICAL]
# 	84 : RootMeanSquared [NUMERICAL]
# 	83 : TotalEnergy [NUMERICAL]
# 	69 : LowGrayLevelRunEmphasis [NUMERICAL]
# 	58 : LongRunEmphasis [NUMERICAL]
# 	57 : Range [NUMERICAL]
# 	41 : Entropy [NUMERICAL]
# 	37 : HighGrayLevelRunEmphasis [NUMERICAL]
# 	36 : InterquartileRange [NUMERICAL]
# 	36 : 90Percentile [NUMERICAL]
# 	35 : Skewness [NUMERICAL]
# 	35 : ShortRunHighGrayLevelEmphasis [NUMERICAL]
# 	35 : Maximum [NUMERICAL]
# 	34 : GrayLevelNonUniformity [NUMERICAL]
# 	29 : RobustMeanAbsoluteDeviation [NUMERICAL]
# 	28 : Uniformity [NUMERICAL]
# 	27 : MeanAbsoluteDeviation [NUMERICAL]
# 	21 : GrayLevelVariance [NUMERICAL]
# 	17 : Median [NUMERICAL]
# 	16 : Variance [NUMERICAL]
# 	16 : Mean [NUMERICAL]
# 	15 : RunEntropy [NUMERICAL]
# 	11 : Minimum [NUMERICAL]
#
# Attribute in nodes with depth <= 5:
# 	344 : GrayLevelNonUniformityNormalized [NUMERICAL]
# 	330 : LongRunLowGrayLevelEmphasis [NUMERICAL]
# 	252 : RunVariance [NUMERICAL]
# 	207 : RunLengthNonUniformityNormalized [NUMERICAL]
# 	196 : ShortRunEmphasis [NUMERICAL]
# 	196 : RunPercentage [NUMERICAL]
# 	141 : Kurtosis [NUMERICAL]
# 	138 : LongRunEmphasis [NUMERICAL]
# 	123 : LongRunHighGrayLevelEmphasis [NUMERICAL]
# 	112 : 10Percentile [NUMERICAL]
# 	104 : ShortRunLowGrayLevelEmphasis [NUMERICAL]
# 	100 : Range [NUMERICAL]
# 	99 : RunLengthNonUniformity [NUMERICAL]
# 	93 : Energy [NUMERICAL]
# 	92 : GrayLevelVariance [NUMERICAL]
# 	87 : RootMeanSquared [NUMERICAL]
# 	86 : TotalEnergy [NUMERICAL]
# 	75 : LowGrayLevelRunEmphasis [NUMERICAL]
# 	64 : GrayLevelNonUniformity [NUMERICAL]
# 	59 : HighGrayLevelRunEmphasis [NUMERICAL]
# 	58 : InterquartileRange [NUMERICAL]
# 	45 : ShortRunHighGrayLevelEmphasis [NUMERICAL]
# 	43 : Entropy [NUMERICAL]
# 	40 : Maximum [NUMERICAL]
# 	38 : Skewness [NUMERICAL]
# 	36 : 90Percentile [NUMERICAL]
# 	35 : MeanAbsoluteDeviation [NUMERICAL]
# 	31 : RobustMeanAbsoluteDeviation [NUMERICAL]
# 	29 : Uniformity [NUMERICAL]
# 	26 : Variance [NUMERICAL]
# 	22 : RunEntropy [NUMERICAL]
# 	18 : Mean [NUMERICAL]
# 	17 : Minimum [NUMERICAL]
# 	17 : Median [NUMERICAL]
#
# Condition type in nodes:
# 	3353 : HigherCondition
# Condition type in nodes with depth <= 0:
# 	298 : HigherCondition
# Condition type in nodes with depth <= 1:
# 	885 : HigherCondition
# Condition type in nodes with depth <= 2:
# 	1757 : HigherCondition
# Condition type in nodes with depth <= 3:
# 	2588 : HigherCondition
# Condition type in nodes with depth <= 5:
# 	3353 : HigherCondition
#
# Training logs:
# Number of iteration to final model: 298
# 	Iter:1 train-loss:1.196054 valid-loss:1.200199  train-accuracy:1.000000 valid-accuracy:1.000000
# 	Iter:2 train-loss:1.040448 valid-loss:1.043878  train-accuracy:1.000000 valid-accuracy:1.000000
# 	Iter:3 train-loss:0.910696 valid-loss:0.913578  train-accuracy:1.000000 valid-accuracy:1.000000
# 	Iter:4 train-loss:0.801022 valid-loss:0.803472  train-accuracy:1.000000 valid-accuracy:1.000000
# 	Iter:5 train-loss:0.707337 valid-loss:0.709440  train-accuracy:1.000000 valid-accuracy:1.000000
# 	Iter:6 train-loss:0.626635 valid-loss:0.628453  train-accuracy:1.000000 valid-accuracy:1.000000
# 	Iter:16 train-loss:0.206036 valid-loss:0.206565  train-accuracy:1.000000 valid-accuracy:1.000000
# 	Iter:26 train-loss:0.073099 valid-loss:0.073279  train-accuracy:1.000000 valid-accuracy:1.000000
# 	Iter:36 train-loss:0.026550 valid-loss:0.026615  train-accuracy:1.000000 valid-accuracy:1.000000
# 	Iter:46 train-loss:0.009722 valid-loss:0.009746  train-accuracy:1.000000 valid-accuracy:1.000000
# 	Iter:56 train-loss:0.003571 valid-loss:0.003579  train-accuracy:1.000000 valid-accuracy:1.000000
# 	Iter:66 train-loss:0.001313 valid-loss:0.001316  train-accuracy:1.000000 valid-accuracy:1.000000
# 	Iter:76 train-loss:0.000483 valid-loss:0.000484  train-accuracy:1.000000 valid-accuracy:1.000000
# 	Iter:86 train-loss:0.000179 valid-loss:0.000178  train-accuracy:1.000000 valid-accuracy:1.000000
# 	Iter:96 train-loss:0.000071 valid-loss:0.000071  train-accuracy:1.000000 valid-accuracy:1.000000
# 	Iter:106 train-loss:0.000032 valid-loss:0.000032  train-accuracy:1.000000 valid-accuracy:1.000000
# 	Iter:116 train-loss:0.000016 valid-loss:0.000016  train-accuracy:1.000000 valid-accuracy:1.000000
# 	Iter:126 train-loss:0.000010 valid-loss:0.000010  train-accuracy:1.000000 valid-accuracy:1.000000
# 	Iter:136 train-loss:0.000007 valid-loss:0.000006  train-accuracy:1.000000 valid-accuracy:1.000000
# 	Iter:146 train-loss:0.000006 valid-loss:0.000005  train-accuracy:1.000000 valid-accuracy:1.000000
# 	Iter:156 train-loss:0.000005 valid-loss:0.000005  train-accuracy:1.000000 valid-accuracy:1.000000
# 	Iter:166 train-loss:0.000005 valid-loss:0.000004  train-accuracy:1.000000 valid-accuracy:1.000000
# 	Iter:176 train-loss:0.000004 valid-loss:0.000004  train-accuracy:1.000000 valid-accuracy:1.000000
# 	Iter:186 train-loss:0.000004 valid-loss:0.000004  train-accuracy:1.000000 valid-accuracy:1.000000
# 	Iter:196 train-loss:0.000004 valid-loss:0.000003  train-accuracy:1.000000 valid-accuracy:1.000000
# 	Iter:206 train-loss:0.000004 valid-loss:0.000003  train-accuracy:1.000000 valid-accuracy:1.000000
# 	Iter:216 train-loss:0.000003 valid-loss:0.000003  train-accuracy:1.000000 valid-accuracy:1.000000
# 	Iter:226 train-loss:0.000003 valid-loss:0.000003  train-accuracy:1.000000 valid-accuracy:1.000000
# 	Iter:236 train-loss:0.000003 valid-loss:0.000003  train-accuracy:1.000000 valid-accuracy:1.000000
# 	Iter:246 train-loss:0.000003 valid-loss:0.000002  train-accuracy:1.000000 valid-accuracy:1.000000
# 	Iter:256 train-loss:0.000002 valid-loss:0.000002  train-accuracy:1.000000 valid-accuracy:1.000000
# 	Iter:266 train-loss:0.000002 valid-loss:0.000002  train-accuracy:1.000000 valid-accuracy:1.000000
# 	Iter:276 train-loss:0.000002 valid-loss:0.000002  train-accuracy:1.000000 valid-accuracy:1.000000
# 	Iter:286 train-loss:0.000002 valid-loss:0.000002  train-accuracy:1.000000 valid-accuracy:1.000000
# 	Iter:296 train-loss:0.000002 valid-loss:0.000002  train-accuracy:1.000000 valid-accuracy:1.000000

# %%
# Model features
model.make_inspector().features()
# Out:
# ["10Percentile" (1; #0),
#  "90Percentile" (1; #1),
#  "Energy" (1; #2),
#  "Entropy" (1; #3),
#  "GrayLevelNonUniformity" (1; #4),
#  "GrayLevelNonUniformityNormalized" (1; #5),
#  "GrayLevelVariance" (1; #6),
#  "HighGrayLevelRunEmphasis" (1; #7),
#  "InterquartileRange" (1; #8),
#  "Kurtosis" (1; #9),
#  "LongRunEmphasis" (1; #10),
#  "LongRunHighGrayLevelEmphasis" (1; #11),
#  "LongRunLowGrayLevelEmphasis" (1; #12),
#  "LowGrayLevelRunEmphasis" (1; #13),
#  "Maximum" (1; #14),
#  "Mean" (1; #15),
#  "MeanAbsoluteDeviation" (1; #16),
#  "Median" (1; #17),
#  "Minimum" (1; #18),
#  "Range" (1; #19),
#  "RobustMeanAbsoluteDeviation" (1; #20),
#  "RootMeanSquared" (1; #21),
#  "RunEntropy" (1; #22),
#  "RunLengthNonUniformity" (1; #23),
#  "RunLengthNonUniformityNormalized" (1; #24),
#  "RunPercentage" (1; #25),
#  "RunVariance" (1; #26),
#  "ShortRunEmphasis" (1; #27),
#  "ShortRunHighGrayLevelEmphasis" (1; #28),
#  "ShortRunLowGrayLevelEmphasis" (1; #29),
#  "Skewness" (1; #30),
#  "TotalEnergy" (1; #31),
#  "Uniformity" (1; #32),
#  "Variance" (1; #33)]

# %%
# Feature importance
model.make_inspector().variable_importances()
# Out:
# {'INV_MEAN_MIN_DEPTH': [("RunVariance" (1; #26), 0.2825309582383618),
#   ("LongRunLowGrayLevelEmphasis" (1; #12), 0.28092982543544326),
#   ("Energy" (1; #2), 0.26293279970839983),
#   ("RootMeanSquared" (1; #21), 0.2538996872586263),
#   ("ShortRunEmphasis" (1; #27), 0.24789195712892514),
#   ("TotalEnergy" (1; #31), 0.2471950636468752),
#   ("RunLengthNonUniformityNormalized" (1; #24), 0.24558764273898215),
#   ("GrayLevelNonUniformityNormalized" (1; #5), 0.2382804348650237),
#   ("RunPercentage" (1; #25), 0.21882161460666985),
#   ("Kurtosis" (1; #9), 0.21448261868814467),
#   ("LowGrayLevelRunEmphasis" (1; #13), 0.2141494155571693),
#   ("ShortRunLowGrayLevelEmphasis" (1; #29), 0.21410021790970551),
#   ("LongRunHighGrayLevelEmphasis" (1; #11), 0.21240167318382844),
#   ("RunLengthNonUniformity" (1; #23), 0.21183121170116828),
#   ("10Percentile" (1; #0), 0.21076898501849936),
#   ("LongRunEmphasis" (1; #10), 0.2103985209495855),
#   ("Range" (1; #19), 0.21019078460908058),
#   ("GrayLevelVariance" (1; #6), 0.209030167468123),
#   ("GrayLevelNonUniformity" (1; #4), 0.20850451462545574),
#   ("InterquartileRange" (1; #8), 0.20841278983153938),
#   ("Entropy" (1; #3), 0.2083429158705066),
#   ("HighGrayLevelRunEmphasis" (1; #7), 0.20833871317519342),
#   ("ShortRunHighGrayLevelEmphasis" (1; #28), 0.2083064261428788),
#   ("Maximum" (1; #14), 0.20827402194000405),
#   ("90Percentile" (1; #1), 0.20824003903174834),
#   ("Uniformity" (1; #32), 0.20802666934702863),
#   ("RobustMeanAbsoluteDeviation" (1; #20), 0.20786006321577377),
#   ("Skewness" (1; #30), 0.20756122157723028),
#   ("MeanAbsoluteDeviation" (1; #16), 0.20753417714217498),
#   ("Mean" (1; #15), 0.20746234865816662),
#   ("Variance" (1; #33), 0.20725369857474615),
#   ("RunEntropy" (1; #22), 0.20723932602180517),
#   ("Median" (1; #17), 0.20722235876970937),
#   ("Minimum" (1; #18), 0.20708067609135075)],
#  'NUM_AS_ROOT': [("RunVariance" (1; #26), 110.0),
#   ("Energy" (1; #2), 73.0),
#   ("RootMeanSquared" (1; #21), 60.0),
#   ("TotalEnergy" (1; #31), 53.0),
#   ("Kurtosis" (1; #9), 2.0)],
#  'SUM_SCORE': [("RunVariance" (1; #26), 664.198613612966),
#   ("LongRunLowGrayLevelEmphasis" (1; #12), 130.66595518598885),
#   ("RunPercentage" (1; #25), 81.10226906055892),
#   ("LowGrayLevelRunEmphasis" (1; #13), 76.04280101243887),
#   ("ShortRunLowGrayLevelEmphasis" (1; #29), 0.4622799143319543),
#   ("Energy" (1; #2), 6.794824579054805e-07),
#   ("RootMeanSquared" (1; #21), 5.006791782910644e-07),
#   ("TotalEnergy" (1; #31), 4.622403721995318e-07),
#   ("RunLengthNonUniformityNormalized" (1; #24), 3.442761697668013e-07),
#   ("ShortRunEmphasis" (1; #27), 2.8982592298271664e-07),
#   ("Kurtosis" (1; #9), 2.457999190023983e-07),
#   ("GrayLevelNonUniformityNormalized" (1; #5), 2.1120699585943277e-07),
#   ("RunLengthNonUniformity" (1; #23), 1.217441341952074e-07),
#   ("10Percentile" (1; #0), 1.027476048362783e-07),
#   ("GrayLevelNonUniformity" (1; #4), 7.292817785294211e-08),
#   ("LongRunHighGrayLevelEmphasis" (1; #11), 4.8803796594240675e-08),
#   ("LongRunEmphasis" (1; #10), 1.981067678703194e-08),
#   ("Mean" (1; #15), 1.9561526529943157e-08),
#   ("HighGrayLevelRunEmphasis" (1; #7), 5.7583148112206426e-09),
#   ("Range" (1; #19), 5.2363259425003324e-09),
#   ("InterquartileRange" (1; #8), 5.199806733854783e-09),
#   ("Variance" (1; #33), 1.755960450853981e-09),
#   ("GrayLevelVariance" (1; #6), 1.582370957588272e-09),
#   ("Entropy" (1; #3), 1.3317398946630397e-09),
#   ("Maximum" (1; #14), 1.2219801420993664e-09),
#   ("90Percentile" (1; #1), 1.214813644714694e-09),
#   ("MeanAbsoluteDeviation" (1; #16), 1.1726934093581987e-09),
#   ("ShortRunHighGrayLevelEmphasis" (1; #28), 1.0049854960692837e-09),
#   ("RobustMeanAbsoluteDeviation" (1; #20), 8.572566065706539e-10),
#   ("RunEntropy" (1; #22), 5.530269946415281e-10),
#   ("Skewness" (1; #30), 3.2934200212573603e-10),
#   ("Minimum" (1; #18), 2.676443858117901e-10),
#   ("Uniformity" (1; #32), 2.4214229356708665e-10),
#   ("Median" (1; #17), 3.9220067367815985e-13)],
#  'NUM_NODES': [("GrayLevelNonUniformityNormalized" (1; #5), 344.0),
#   ("LongRunLowGrayLevelEmphasis" (1; #12), 330.0),
#   ("RunVariance" (1; #26), 252.0),
#   ("RunLengthNonUniformityNormalized" (1; #24), 207.0),
#   ("RunPercentage" (1; #25), 196.0),
#   ("ShortRunEmphasis" (1; #27), 196.0),
#   ("Kurtosis" (1; #9), 141.0),
#   ("LongRunEmphasis" (1; #10), 138.0),
#   ("LongRunHighGrayLevelEmphasis" (1; #11), 123.0),
#   ("10Percentile" (1; #0), 112.0),
#   ("ShortRunLowGrayLevelEmphasis" (1; #29), 104.0),
#   ("Range" (1; #19), 100.0),
#   ("RunLengthNonUniformity" (1; #23), 99.0),
#   ("Energy" (1; #2), 93.0),
#   ("GrayLevelVariance" (1; #6), 92.0),
#   ("RootMeanSquared" (1; #21), 87.0),
#   ("TotalEnergy" (1; #31), 86.0),
#   ("LowGrayLevelRunEmphasis" (1; #13), 75.0),
#   ("GrayLevelNonUniformity" (1; #4), 64.0),
#   ("HighGrayLevelRunEmphasis" (1; #7), 59.0),
#   ("InterquartileRange" (1; #8), 58.0),
#   ("ShortRunHighGrayLevelEmphasis" (1; #28), 45.0),
#   ("Entropy" (1; #3), 43.0),
#   ("Maximum" (1; #14), 40.0),
#   ("Skewness" (1; #30), 38.0),
#   ("90Percentile" (1; #1), 36.0),
#   ("MeanAbsoluteDeviation" (1; #16), 35.0),
#   ("RobustMeanAbsoluteDeviation" (1; #20), 31.0),
#   ("Uniformity" (1; #32), 29.0),
#   ("Variance" (1; #33), 26.0),
#   ("RunEntropy" (1; #22), 22.0),
#   ("Mean" (1; #15), 18.0),
#   ("Median" (1; #17), 17.0),
#   ("Minimum" (1; #18), 17.0)]}

# %%
# Model self evaluation
model.make_inspector().evaluation()
# Out:
# Evaluation(num_examples=None, accuracy=1.0, loss=1.534924763291201e-06, rmse=None, ndcg=None, aucs=None, auuc=None, qini=None)

# %%
logs = model.make_inspector().training_logs()

plt.figure(figsize=(12, 4))
plt.subplot(1, 2, 1)
plt.plot([log.num_trees for log in logs], [log.evaluation.accuracy for log in logs])
plt.xlabel("Number of trees")
plt.ylabel("Accuracy (out-of-bag)")
plt.subplot(1, 2, 2)
plt.plot([log.num_trees for log in logs], [log.evaluation.loss for log in logs])
plt.xlabel("Number of trees")
plt.ylabel("Logloss (out-of-bag)")
plt.show()

# %% [markdown]
# Calculate the score of our hold-out validation dataset

# %%
predictions = model.predict(val_ds)
y_true      = validation_data["label"]

from sklearn.metrics import roc_auc_score
ROC_AUC = roc_auc_score(y_true, predictions)
print("The ROC AUC score is %.5f" % ROC_AUC )
# Out:
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 70ms/step
# The ROC AUC score is 1.00000

# %%
# Compute binary classification metrics with sklearn
import numpy as np
from sklearn.metrics import (
    accuracy_score,
    precision_score,
    recall_score,
    f1_score,
    roc_auc_score,
    average_precision_score,
    confusion_matrix,
    classification_report,
    matthews_corrcoef,
    log_loss,
    brier_score_loss,
)

# Get predictions (probabilities or class labels)
preds = model.predict(test_ds)
# If model outputs probabilities, convert to labels by threshold 0.5
if preds.ndim == 2:
    # For TFDF classification, preds may be class probabilities with shape (N, 2)
    if preds.shape[1] == 2:
        pos_probs = preds[:, 1]
    else:
        # If single-probability column (positive class)
        pos_probs = preds[:, -1]
    y_pred = (pos_probs >= 0.5).astype(int)
else:
    # Already class labels
    y_pred = preds.astype(int)
    pos_probs = None

# Ground truth labels (must be 0/1 integers)
y_true = test_data["label"].astype(int).to_numpy()

# Core metrics
metrics = {}
metrics["accuracy"] = accuracy_score(y_true, y_pred)
metrics["precision"] = precision_score(y_true, y_pred, zero_division=0)
metrics["recall"] = recall_score(y_true, y_pred, zero_division=0)
metrics["f1"] = f1_score(y_true, y_pred, zero_division=0)
metrics["mcc"] = matthews_corrcoef(y_true, y_pred)

# Probabilistic metrics (only if we have probabilities)
if pos_probs is not None:
    metrics["roc_auc"] = roc_auc_score(y_true, pos_probs)
    metrics["pr_auc"] = average_precision_score(y_true, pos_probs)
    metrics["log_loss"] = log_loss(y_true, pos_probs, labels=[0,1])
    metrics["brier_score"] = brier_score_loss(y_true, pos_probs)

# Confusion matrix and detailed report
cm = confusion_matrix(y_true, y_pred, labels=[0,1])
report = classification_report(y_true, y_pred, digits=4)

print("Sklearn binary metrics:")
for k, v in metrics.items():
    print(f"{k}: {v:.4f}")
print("\nConfusion matrix:\n", cm)
print("\nClassification report:\n", report)
# Out:
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 72ms/step
# Sklearn binary metrics:
# accuracy: 1.0000
# precision: 1.0000
# recall: 1.0000
# f1: 1.0000
# mcc: 1.0000
# roc_auc: 1.0000
# pr_auc: 1.0000
# log_loss: 0.0000
# brier_score: 0.0000
#
# Confusion matrix:
#  [[109   0]
#  [  0 113]]
#
# Classification report:
#                precision    recall  f1-score   support
#
#            0     1.0000    1.0000    1.0000       109
#            1     1.0000    1.0000    1.0000       113
#
#     accuracy                         1.0000       222
#    macro avg     1.0000    1.0000    1.0000       222
# weighted avg     1.0000    1.0000    1.0000       222
