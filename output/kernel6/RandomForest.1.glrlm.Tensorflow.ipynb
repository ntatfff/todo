# %%
# Import packages and modules
import numpy  as np
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow_decision_forests as tfdf

from sklearn.model_selection import train_test_split
# Out:
# 2026-08-12 05:58:39.454525: I tensorflow/core/util/port.cc:113] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2026-08-12 05:58:39.804008: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2026-08-12 05:58:44.339998: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
# Check the version of TensorFlow Decision Forests
print("Found TensorFlow Decision Forests v" + tfdf.__version__)
# Out:
# Found TensorFlow Decision Forests v1.9.1

# %%
datasetPath = 'dataset/firstorder/kernel5-radius5/dataset.csv'

# %%
# Parameters
datasetPath = "dataset/glrlm/kernel6-radius6/1.dataset.csv"

# %%
# train/validation/test = 70/10/20
dataset = pd.read_csv(datasetPath)

train_data, temp_data = train_test_split(dataset, test_size=0.3, random_state=42)
validation_data, test_data = train_test_split(temp_data, test_size=2/3, random_state=42)

# %%
from sklearn.utils.class_weight import compute_class_weight

# tinh class weight tren tap train
classes = np.array([0, 1])
weights = compute_class_weight(class_weight="balanced", classes=classes, y=train_data["label"])
class_weight = {0: weights[0], 1: weights[1]}

# gan sample_weight cho tung dong
train_data["sample_weight"] = train_data["label"].map(class_weight)
validation_data["sample_weight"] = validation_data["label"].map(class_weight)
test_data["sample_weight"] = test_data["label"].map(class_weight)

# Convert the dataset into a TensorFlow dataset.
train_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    train_data, label="label", weight="sample_weight"
)         
val_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    validation_data, label="label", weight="sample_weight"
)
test_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    test_data, label="label", weight="sample_weight"
)
# Out:
# 2026-08-12 05:58:59.530843: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:984] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2026-08-12 05:58:59.532708: W tensorflow/core/common_runtime/gpu/gpu_device.cc:2251] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...

# %%
import keras

# %%
# %%time

# Train a Random Forest model.
model = tfdf.keras.RandomForestModel()

# Add evaluation metrics
model.compile(
    metrics=["accuracy"]
)
model.fit(x=train_ds)

# # Train a Gradient Boosted Trees model.
# model = tfdf.keras.GradientBoostedTreesModel(num_trees=1500)
# model.fit(train_ds)
# Out:
# Use /tmp/tmpuc0ygssx as temporary training directory
# Reading training dataset...
# Training dataset read in 0:00:02.439477. Found 450 examples.
# Training model...
# Model trained in 0:00:00.050234
# Compiling model...
# [INFO 26-08-12 05:59:02.1746 UTC kernel.cc:1233] Loading model from path /tmp/tmpuc0ygssx/model/ with prefix 20a95ec5f9a14cec
# [INFO 26-08-12 05:59:02.1829 UTC decision_forest.cc:734] Model loaded with 300 root(s), 7360 node(s), and 16 input feature(s).
# [INFO 26-08-12 05:59:02.1829 UTC abstract_model.cc:1362] Engine "RandomForestOptPred" built
# [INFO 26-08-12 05:59:02.1829 UTC kernel.cc:1061] Use fast generic engine
# Model compiled.
# CPU times: user 5.54 s, sys: 87.3 ms, total: 5.62 s
# Wall time: 5.46 s

# %%
# Evaluate the model
evaluate = model.evaluate(val_ds, return_dict=True)
print()

for name, value in evaluate.items():
    print(f"{name}: {value:.4f}")
# Out:
# WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 1/1 [==============================] - ETA: 0s - loss: 0.0000e+00 - accuracy: 0.9531
# 1/1 [==============================] - 3s 3s/step - loss: 0.0000e+00 - accuracy: 0.9531
# loss: 0.0000
# accuracy: 0.9531

# %%
# Model Summary
model.summary()
# Out:
# Model: "random_forest_model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
# =================================================================
# Total params: 1 (1.00 Byte)
# Trainable params: 0 (0.00 Byte)
# Non-trainable params: 1 (1.00 Byte)
# _________________________________________________________________
# Type: "RANDOM_FOREST"
# Task: CLASSIFICATION
# Label: "__LABEL"
#
# Input Features (16):
# 	GrayLevelNonUniformity
# 	GrayLevelNonUniformityNormalized
# 	GrayLevelVariance
# 	HighGrayLevelRunEmphasis
# 	LongRunEmphasis
# 	LongRunHighGrayLevelEmphasis
# 	LongRunLowGrayLevelEmphasis
# 	LowGrayLevelRunEmphasis
# 	RunEntropy
# 	RunLengthNonUniformity
# 	RunLengthNonUniformityNormalized
# 	RunPercentage
# 	RunVariance
# 	ShortRunEmphasis
# 	ShortRunHighGrayLevelEmphasis
# 	ShortRunLowGrayLevelEmphasis
#
# Trained with weights
#
# Variable Importance: INV_MEAN_MIN_DEPTH:
#     1.     "LongRunHighGrayLevelEmphasis"  0.323097 ################
#     2.         "HighGrayLevelRunEmphasis"  0.285296 ###########
#     3.    "ShortRunHighGrayLevelEmphasis"  0.243266 #####
#     4.          "LowGrayLevelRunEmphasis"  0.233574 ####
#     5.     "ShortRunLowGrayLevelEmphasis"  0.227179 ###
#     6.                       "RunEntropy"  0.214411 ##
#     7. "GrayLevelNonUniformityNormalized"  0.205604
#     8.      "LongRunLowGrayLevelEmphasis"  0.204287
#     9.                "GrayLevelVariance"  0.203290
#    10.           "GrayLevelNonUniformity"  0.201587
#    11.                      "RunVariance"  0.199947
#    12.                    "RunPercentage"  0.199728
#    13.                  "LongRunEmphasis"  0.199670
#    14.                 "ShortRunEmphasis"  0.199269
#    15. "RunLengthNonUniformityNormalized"  0.198880
#    16.           "RunLengthNonUniformity"  0.198470
#
# Variable Importance: NUM_AS_ROOT:
#     1.     "LongRunHighGrayLevelEmphasis" 88.000000 ################
#     2.         "HighGrayLevelRunEmphasis" 81.000000 ##############
#     3.          "LowGrayLevelRunEmphasis" 42.000000 #######
#     4.     "ShortRunLowGrayLevelEmphasis" 31.000000 #####
#     5.    "ShortRunHighGrayLevelEmphasis" 28.000000 ####
#     6.      "LongRunLowGrayLevelEmphasis" 10.000000 #
#     7. "GrayLevelNonUniformityNormalized"  6.000000
#     8.                  "LongRunEmphasis"  5.000000
#     9.                      "RunVariance"  4.000000
#    10.                       "RunEntropy"  2.000000
#    11.                    "RunPercentage"  2.000000
#    12.           "GrayLevelNonUniformity"  1.000000
#
# Variable Importance: NUM_NODES:
#     1.     "LongRunHighGrayLevelEmphasis" 501.000000 ################
#     2.         "HighGrayLevelRunEmphasis" 346.000000 #########
#     3.    "ShortRunHighGrayLevelEmphasis" 308.000000 #######
#     4.          "LowGrayLevelRunEmphasis" 279.000000 ######
#     5.     "ShortRunLowGrayLevelEmphasis" 258.000000 #####
#     6.                       "RunEntropy" 255.000000 #####
#     7.           "GrayLevelNonUniformity" 191.000000 ##
#     8. "GrayLevelNonUniformityNormalized" 181.000000 ##
#     9.      "LongRunLowGrayLevelEmphasis" 179.000000 ##
#    10.                "GrayLevelVariance" 168.000000 #
#    11. "RunLengthNonUniformityNormalized" 162.000000 #
#    12.                 "ShortRunEmphasis" 153.000000
#    13.                    "RunPercentage" 146.000000
#    14.                      "RunVariance" 138.000000
#    15.           "RunLengthNonUniformity" 134.000000
#    16.                  "LongRunEmphasis" 131.000000
#
# Variable Importance: SUM_SCORE:
#     1.     "LongRunHighGrayLevelEmphasis" 26059.047775 ################
#     2.         "HighGrayLevelRunEmphasis" 17172.935578 ##########
#     3.          "LowGrayLevelRunEmphasis" 9224.100278 #####
#     4.    "ShortRunHighGrayLevelEmphasis" 8179.914362 ####
#     5.     "ShortRunLowGrayLevelEmphasis" 7372.579623 ###
#     6.                       "RunEntropy" 3364.582296 #
#     7.      "LongRunLowGrayLevelEmphasis" 2642.644731
#     8. "GrayLevelNonUniformityNormalized" 1999.688377
#     9.           "GrayLevelNonUniformity" 1951.366663
#    10.                "GrayLevelVariance" 1708.402015
#    11. "RunLengthNonUniformityNormalized" 1521.161166
#    12.                    "RunPercentage" 1381.183072
#    13.                 "ShortRunEmphasis" 1294.351559
#    14.                  "LongRunEmphasis" 1222.879543
#    15.                      "RunVariance" 1194.032324
#    16.           "RunLengthNonUniformity" 1168.489878
#
#
#
# Winner takes all: true
# Out-of-bag evaluation: accuracy:0.928087 logloss:0.233693
# Number of trees: 300
# Total number of nodes: 7360
#
# Number of nodes by tree:
# Count: 300 Average: 24.5333 StdDev: 3.66181
# Min: 15 Max: 35 Ignored: 0
# ----------------------------------------------
# [ 15, 16)  5   1.67%   1.67% #
# [ 16, 17)  0   0.00%   1.67%
# [ 17, 18)  7   2.33%   4.00% #
# [ 18, 19)  0   0.00%   4.00%
# [ 19, 20) 24   8.00%  12.00% ###
# [ 20, 21)  0   0.00%  12.00%
# [ 21, 22) 32  10.67%  22.67% ####
# [ 22, 23)  0   0.00%  22.67%
# [ 23, 24) 56  18.67%  41.33% ########
# [ 24, 25)  0   0.00%  41.33%
# [ 25, 26) 73  24.33%  65.67% ##########
# [ 26, 27)  0   0.00%  65.67%
# [ 27, 28) 57  19.00%  84.67% ########
# [ 28, 29)  0   0.00%  84.67%
# [ 29, 30) 26   8.67%  93.33% ####
# [ 30, 31)  0   0.00%  93.33%
# [ 31, 32) 15   5.00%  98.33% ##
# [ 32, 33)  0   0.00%  98.33%
# [ 33, 34)  4   1.33%  99.67% #
# [ 34, 35]  1   0.33% 100.00%
#
# Depth by leafs:
# Count: 3830 Average: 4.36397 StdDev: 1.50929
# Min: 1 Max: 9 Ignored: 0
# ----------------------------------------------
# [ 1, 2)  17   0.44%   0.44%
# [ 2, 3) 408  10.65%  11.10% ####
# [ 3, 4) 745  19.45%  30.55% ########
# [ 4, 5) 950  24.80%  55.35% ##########
# [ 5, 6) 846  22.09%  77.44% #########
# [ 6, 7) 536  13.99%  91.44% ######
# [ 7, 8) 240   6.27%  97.70% ###
# [ 8, 9)  72   1.88%  99.58% #
# [ 9, 9]  16   0.42% 100.00%
#
# Number of training obs by leaf:
# Count: 3830 Average: 35.248 StdDev: 62.8843
# Min: 5 Max: 358 Ignored: 0
# ----------------------------------------------
# [   5,  22) 2727  71.20%  71.20% ##########
# [  22,  40)  289   7.55%  78.75% #
# [  40,  58)  267   6.97%  85.72% #
# [  58,  75)   66   1.72%  87.44%
# [  75,  93)   63   1.64%  89.09%
# [  93, 111)   57   1.49%  90.57%
# [ 111, 128)   45   1.17%  91.75%
# [ 128, 146)   24   0.63%  92.38%
# [ 146, 164)    4   0.10%  92.48%
# [ 164, 182)    7   0.18%  92.66%
# [ 182, 199)   46   1.20%  93.86%
# [ 199, 217)   64   1.67%  95.54%
# [ 217, 235)   44   1.15%  96.68%
# [ 235, 252)   43   1.12%  97.81%
# [ 252, 270)   28   0.73%  98.54%
# [ 270, 288)   18   0.47%  99.01%
# [ 288, 305)   18   0.47%  99.48%
# [ 305, 323)    7   0.18%  99.66%
# [ 323, 341)    9   0.23%  99.90%
# [ 341, 358]    4   0.10% 100.00%
#
# Attribute in nodes:
# 	501 : LongRunHighGrayLevelEmphasis [NUMERICAL]
# 	346 : HighGrayLevelRunEmphasis [NUMERICAL]
# 	308 : ShortRunHighGrayLevelEmphasis [NUMERICAL]
# 	279 : LowGrayLevelRunEmphasis [NUMERICAL]
# 	258 : ShortRunLowGrayLevelEmphasis [NUMERICAL]
# 	255 : RunEntropy [NUMERICAL]
# 	191 : GrayLevelNonUniformity [NUMERICAL]
# 	181 : GrayLevelNonUniformityNormalized [NUMERICAL]
# 	179 : LongRunLowGrayLevelEmphasis [NUMERICAL]
# 	168 : GrayLevelVariance [NUMERICAL]
# 	162 : RunLengthNonUniformityNormalized [NUMERICAL]
# 	153 : ShortRunEmphasis [NUMERICAL]
# 	146 : RunPercentage [NUMERICAL]
# 	138 : RunVariance [NUMERICAL]
# 	134 : RunLengthNonUniformity [NUMERICAL]
# 	131 : LongRunEmphasis [NUMERICAL]
#
# Attribute in nodes with depth <= 0:
# 	88 : LongRunHighGrayLevelEmphasis [NUMERICAL]
# 	81 : HighGrayLevelRunEmphasis [NUMERICAL]
# 	42 : LowGrayLevelRunEmphasis [NUMERICAL]
# 	31 : ShortRunLowGrayLevelEmphasis [NUMERICAL]
# 	28 : ShortRunHighGrayLevelEmphasis [NUMERICAL]
# 	10 : LongRunLowGrayLevelEmphasis [NUMERICAL]
# 	6 : GrayLevelNonUniformityNormalized [NUMERICAL]
# 	5 : LongRunEmphasis [NUMERICAL]
# 	4 : RunVariance [NUMERICAL]
# 	2 : RunPercentage [NUMERICAL]
# 	2 : RunEntropy [NUMERICAL]
# 	1 : GrayLevelNonUniformity [NUMERICAL]
#
# Attribute in nodes with depth <= 1:
# 	216 : LongRunHighGrayLevelEmphasis [NUMERICAL]
# 	179 : HighGrayLevelRunEmphasis [NUMERICAL]
# 	122 : ShortRunHighGrayLevelEmphasis [NUMERICAL]
# 	101 : LowGrayLevelRunEmphasis [NUMERICAL]
# 	76 : ShortRunLowGrayLevelEmphasis [NUMERICAL]
# 	50 : RunEntropy [NUMERICAL]
# 	31 : LongRunLowGrayLevelEmphasis [NUMERICAL]
# 	30 : GrayLevelNonUniformityNormalized [NUMERICAL]
# 	23 : GrayLevelVariance [NUMERICAL]
# 	22 : GrayLevelNonUniformity [NUMERICAL]
# 	10 : LongRunEmphasis [NUMERICAL]
# 	7 : RunPercentage [NUMERICAL]
# 	5 : RunVariance [NUMERICAL]
# 	4 : ShortRunEmphasis [NUMERICAL]
# 	4 : RunLengthNonUniformity [NUMERICAL]
# 	3 : RunLengthNonUniformityNormalized [NUMERICAL]
#
# Attribute in nodes with depth <= 2:
# 	333 : LongRunHighGrayLevelEmphasis [NUMERICAL]
# 	241 : HighGrayLevelRunEmphasis [NUMERICAL]
# 	176 : ShortRunHighGrayLevelEmphasis [NUMERICAL]
# 	156 : LowGrayLevelRunEmphasis [NUMERICAL]
# 	142 : ShortRunLowGrayLevelEmphasis [NUMERICAL]
# 	98 : RunEntropy [NUMERICAL]
# 	69 : LongRunLowGrayLevelEmphasis [NUMERICAL]
# 	66 : GrayLevelNonUniformityNormalized [NUMERICAL]
# 	62 : GrayLevelVariance [NUMERICAL]
# 	51 : GrayLevelNonUniformity [NUMERICAL]
# 	47 : RunPercentage [NUMERICAL]
# 	45 : LongRunEmphasis [NUMERICAL]
# 	42 : RunLengthNonUniformityNormalized [NUMERICAL]
# 	40 : ShortRunEmphasis [NUMERICAL]
# 	37 : RunLengthNonUniformity [NUMERICAL]
# 	36 : RunVariance [NUMERICAL]
#
# Attribute in nodes with depth <= 3:
# 	417 : LongRunHighGrayLevelEmphasis [NUMERICAL]
# 	289 : HighGrayLevelRunEmphasis [NUMERICAL]
# 	219 : ShortRunHighGrayLevelEmphasis [NUMERICAL]
# 	201 : LowGrayLevelRunEmphasis [NUMERICAL]
# 	189 : ShortRunLowGrayLevelEmphasis [NUMERICAL]
# 	165 : RunEntropy [NUMERICAL]
# 	110 : LongRunLowGrayLevelEmphasis [NUMERICAL]
# 	106 : GrayLevelVariance [NUMERICAL]
# 	101 : GrayLevelNonUniformityNormalized [NUMERICAL]
# 	98 : GrayLevelNonUniformity [NUMERICAL]
# 	92 : RunLengthNonUniformityNormalized [NUMERICAL]
# 	89 : ShortRunEmphasis [NUMERICAL]
# 	86 : RunVariance [NUMERICAL]
# 	85 : RunPercentage [NUMERICAL]
# 	83 : LongRunEmphasis [NUMERICAL]
# 	82 : RunLengthNonUniformity [NUMERICAL]
#
# Attribute in nodes with depth <= 5:
# 	485 : LongRunHighGrayLevelEmphasis [NUMERICAL]
# 	332 : HighGrayLevelRunEmphasis [NUMERICAL]
# 	292 : ShortRunHighGrayLevelEmphasis [NUMERICAL]
# 	267 : LowGrayLevelRunEmphasis [NUMERICAL]
# 	245 : ShortRunLowGrayLevelEmphasis [NUMERICAL]
# 	243 : RunEntropy [NUMERICAL]
# 	180 : GrayLevelNonUniformity [NUMERICAL]
# 	168 : GrayLevelNonUniformityNormalized [NUMERICAL]
# 	164 : LongRunLowGrayLevelEmphasis [NUMERICAL]
# 	159 : GrayLevelVariance [NUMERICAL]
# 	151 : RunLengthNonUniformityNormalized [NUMERICAL]
# 	138 : ShortRunEmphasis [NUMERICAL]
# 	137 : RunPercentage [NUMERICAL]
# 	128 : LongRunEmphasis [NUMERICAL]
# 	127 : RunVariance [NUMERICAL]
# 	126 : RunLengthNonUniformity [NUMERICAL]
#
# Condition type in nodes:
# 	3530 : HigherCondition
# Condition type in nodes with depth <= 0:
# 	300 : HigherCondition
# Condition type in nodes with depth <= 1:
# 	883 : HigherCondition
# Condition type in nodes with depth <= 2:
# 	1641 : HigherCondition
# Condition type in nodes with depth <= 3:
# 	2412 : HigherCondition
# Condition type in nodes with depth <= 5:
# 	3342 : HigherCondition
# Node format: NOT_SET
#
# Training OOB:
# 	trees: 1, Out-of-bag evaluation: accuracy:0.91127 logloss:3.19814
# 	trees: 13, Out-of-bag evaluation: accuracy:0.901635 logloss:2.25918
# 	trees: 23, Out-of-bag evaluation: accuracy:0.897367 logloss:1.32129
# 	trees: 34, Out-of-bag evaluation: accuracy:0.924161 logloss:0.975247
# 	trees: 44, Out-of-bag evaluation: accuracy:0.924161 logloss:0.695655
# 	trees: 54, Out-of-bag evaluation: accuracy:0.926779 logloss:0.695367
# 	trees: 64, Out-of-bag evaluation: accuracy:0.919426 logloss:0.701586
# 	trees: 75, Out-of-bag evaluation: accuracy:0.913382 logloss:0.709645
# 	trees: 85, Out-of-bag evaluation: accuracy:0.920735 logloss:0.709273
# 	trees: 95, Out-of-bag evaluation: accuracy:0.913382 logloss:0.707355
# 	trees: 105, Out-of-bag evaluation: accuracy:0.913382 logloss:0.708682
# 	trees: 115, Out-of-bag evaluation: accuracy:0.913382 logloss:0.711686
# 	trees: 125, Out-of-bag evaluation: accuracy:0.91469 logloss:0.704923
# 	trees: 136, Out-of-bag evaluation: accuracy:0.91469 logloss:0.222204
# 	trees: 147, Out-of-bag evaluation: accuracy:0.913382 logloss:0.220673
# 	trees: 157, Out-of-bag evaluation: accuracy:0.912073 logloss:0.223496
# 	trees: 168, Out-of-bag evaluation: accuracy:0.919426 logloss:0.226473
# 	trees: 178, Out-of-bag evaluation: accuracy:0.928087 logloss:0.22892
# 	trees: 188, Out-of-bag evaluation: accuracy:0.920735 logloss:0.229477
# 	trees: 198, Out-of-bag evaluation: accuracy:0.920735 logloss:0.228844
# 	trees: 208, Out-of-bag evaluation: accuracy:0.913382 logloss:0.230123
# 	trees: 218, Out-of-bag evaluation: accuracy:0.913382 logloss:0.230084
# 	trees: 229, Out-of-bag evaluation: accuracy:0.913382 logloss:0.233422
# 	trees: 239, Out-of-bag evaluation: accuracy:0.920735 logloss:0.233141
# 	trees: 249, Out-of-bag evaluation: accuracy:0.928087 logloss:0.233752
# 	trees: 260, Out-of-bag evaluation: accuracy:0.920735 logloss:0.234189
# 	trees: 272, Out-of-bag evaluation: accuracy:0.928087 logloss:0.235127
# 	trees: 282, Out-of-bag evaluation: accuracy:0.928087 logloss:0.234634
# 	trees: 292, Out-of-bag evaluation: accuracy:0.928087 logloss:0.235727
# 	trees: 300, Out-of-bag evaluation: accuracy:0.928087 logloss:0.233693

# %%
# Model features
model.make_inspector().features()
# Out:
# ["GrayLevelNonUniformity" (1; #0),
#  "GrayLevelNonUniformityNormalized" (1; #1),
#  "GrayLevelVariance" (1; #2),
#  "HighGrayLevelRunEmphasis" (1; #3),
#  "LongRunEmphasis" (1; #4),
#  "LongRunHighGrayLevelEmphasis" (1; #5),
#  "LongRunLowGrayLevelEmphasis" (1; #6),
#  "LowGrayLevelRunEmphasis" (1; #7),
#  "RunEntropy" (1; #8),
#  "RunLengthNonUniformity" (1; #9),
#  "RunLengthNonUniformityNormalized" (1; #10),
#  "RunPercentage" (1; #11),
#  "RunVariance" (1; #12),
#  "ShortRunEmphasis" (1; #13),
#  "ShortRunHighGrayLevelEmphasis" (1; #14),
#  "ShortRunLowGrayLevelEmphasis" (1; #15)]

# %%
# Feature importance
model.make_inspector().variable_importances()
# Out:
# {'INV_MEAN_MIN_DEPTH': [("LongRunHighGrayLevelEmphasis" (1; #5),
#    0.3230967420841963),
#   ("HighGrayLevelRunEmphasis" (1; #3), 0.285295800039166),
#   ("ShortRunHighGrayLevelEmphasis" (1; #14), 0.24326579891539238),
#   ("LowGrayLevelRunEmphasis" (1; #7), 0.23357389902292353),
#   ("ShortRunLowGrayLevelEmphasis" (1; #15), 0.22717893996209235),
#   ("RunEntropy" (1; #8), 0.21441126546736214),
#   ("GrayLevelNonUniformityNormalized" (1; #1), 0.20560415931044718),
#   ("LongRunLowGrayLevelEmphasis" (1; #6), 0.20428740433912446),
#   ("GrayLevelVariance" (1; #2), 0.20329021122336063),
#   ("GrayLevelNonUniformity" (1; #0), 0.20158693230194383),
#   ("RunVariance" (1; #12), 0.1999473961412639),
#   ("RunPercentage" (1; #11), 0.19972831535534888),
#   ("LongRunEmphasis" (1; #4), 0.199670466538413),
#   ("ShortRunEmphasis" (1; #13), 0.19926926246285168),
#   ("RunLengthNonUniformityNormalized" (1; #10), 0.19887967955483662),
#   ("RunLengthNonUniformity" (1; #9), 0.19847043755504856)],
#  'NUM_AS_ROOT': [("LongRunHighGrayLevelEmphasis" (1; #5), 88.0),
#   ("HighGrayLevelRunEmphasis" (1; #3), 81.0),
#   ("LowGrayLevelRunEmphasis" (1; #7), 42.0),
#   ("ShortRunLowGrayLevelEmphasis" (1; #15), 31.0),
#   ("ShortRunHighGrayLevelEmphasis" (1; #14), 28.0),
#   ("LongRunLowGrayLevelEmphasis" (1; #6), 10.0),
#   ("GrayLevelNonUniformityNormalized" (1; #1), 6.0),
#   ("LongRunEmphasis" (1; #4), 5.0),
#   ("RunVariance" (1; #12), 4.0),
#   ("RunEntropy" (1; #8), 2.0),
#   ("RunPercentage" (1; #11), 2.0),
#   ("GrayLevelNonUniformity" (1; #0), 1.0)],
#  'SUM_SCORE': [("LongRunHighGrayLevelEmphasis" (1; #5), 26059.04777463886),
#   ("HighGrayLevelRunEmphasis" (1; #3), 17172.935578440334),
#   ("LowGrayLevelRunEmphasis" (1; #7), 9224.100277817075),
#   ("ShortRunHighGrayLevelEmphasis" (1; #14), 8179.914361983064),
#   ("ShortRunLowGrayLevelEmphasis" (1; #15), 7372.5796231607765),
#   ("RunEntropy" (1; #8), 3364.5822956982406),
#   ("LongRunLowGrayLevelEmphasis" (1; #6), 2642.6447311155616),
#   ("GrayLevelNonUniformityNormalized" (1; #1), 1999.6883767929005),
#   ("GrayLevelNonUniformity" (1; #0), 1951.3666628009898),
#   ("GrayLevelVariance" (1; #2), 1708.4020145322615),
#   ("RunLengthNonUniformityNormalized" (1; #10), 1521.161165971032),
#   ("RunPercentage" (1; #11), 1381.1830717185978),
#   ("ShortRunEmphasis" (1; #13), 1294.3515592489432),
#   ("LongRunEmphasis" (1; #4), 1222.8795427507719),
#   ("RunVariance" (1; #12), 1194.032324175447),
#   ("RunLengthNonUniformity" (1; #9), 1168.4898780737446)],
#  'NUM_NODES': [("LongRunHighGrayLevelEmphasis" (1; #5), 501.0),
#   ("HighGrayLevelRunEmphasis" (1; #3), 346.0),
#   ("ShortRunHighGrayLevelEmphasis" (1; #14), 308.0),
#   ("LowGrayLevelRunEmphasis" (1; #7), 279.0),
#   ("ShortRunLowGrayLevelEmphasis" (1; #15), 258.0),
#   ("RunEntropy" (1; #8), 255.0),
#   ("GrayLevelNonUniformity" (1; #0), 191.0),
#   ("GrayLevelNonUniformityNormalized" (1; #1), 181.0),
#   ("LongRunLowGrayLevelEmphasis" (1; #6), 179.0),
#   ("GrayLevelVariance" (1; #2), 168.0),
#   ("RunLengthNonUniformityNormalized" (1; #10), 162.0),
#   ("ShortRunEmphasis" (1; #13), 153.0),
#   ("RunPercentage" (1; #11), 146.0),
#   ("RunVariance" (1; #12), 138.0),
#   ("RunLengthNonUniformity" (1; #9), 134.0),
#   ("LongRunEmphasis" (1; #4), 131.0)]}

# %%
# Model self evaluation
model.make_inspector().evaluation()
# Out:
# Evaluation(num_examples=450, accuracy=0.9280874648195507, loss=0.23369306984491237, rmse=None, ndcg=None, aucs=None, auuc=None, qini=None)

# %%
logs = model.make_inspector().training_logs()

plt.figure(figsize=(12, 4))
plt.subplot(1, 2, 1)
plt.plot([log.num_trees for log in logs], [log.evaluation.accuracy for log in logs])
plt.xlabel("Number of trees")
plt.ylabel("Accuracy (out-of-bag)")
plt.subplot(1, 2, 2)
plt.plot([log.num_trees for log in logs], [log.evaluation.loss for log in logs])
plt.xlabel("Number of trees")
plt.ylabel("Logloss (out-of-bag)")
plt.show()

# %% [markdown]
# Calculate the score of our hold-out validation dataset

# %%
predictions = model.predict(val_ds)
y_true      = validation_data["label"]

from sklearn.metrics import roc_auc_score
ROC_AUC = roc_auc_score(y_true, predictions)
print("The ROC AUC score is %.5f" % ROC_AUC )
# Out:
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 60ms/step
# The ROC AUC score is 0.96667

# %%
# Compute binary classification metrics with sklearn
import numpy as np
from sklearn.metrics import (
    accuracy_score,
    precision_score,
    recall_score,
    f1_score,
    roc_auc_score,
    average_precision_score,
    confusion_matrix,
    classification_report,
    matthews_corrcoef,
    log_loss,
    brier_score_loss,
)

# Get predictions (probabilities or class labels)
preds = model.predict(test_ds)
# If model outputs probabilities, convert to labels by threshold 0.5
if preds.ndim == 2:
    # For TFDF classification, preds may be class probabilities with shape (N, 2)
    if preds.shape[1] == 2:
        pos_probs = preds[:, 1]
    else:
        # If single-probability column (positive class)
        pos_probs = preds[:, -1]
    y_pred = (pos_probs >= 0.5).astype(int)
else:
    # Already class labels
    y_pred = preds.astype(int)
    pos_probs = None

# Ground truth labels (must be 0/1 integers)
y_true = test_data["label"].astype(int).to_numpy()

# Core metrics
metrics = {}
metrics["accuracy"] = accuracy_score(y_true, y_pred)
metrics["precision"] = precision_score(y_true, y_pred, zero_division=0)
metrics["recall"] = recall_score(y_true, y_pred, zero_division=0)
metrics["f1"] = f1_score(y_true, y_pred, zero_division=0)
metrics["mcc"] = matthews_corrcoef(y_true, y_pred)

# Probabilistic metrics (only if we have probabilities)
if pos_probs is not None:
    metrics["roc_auc"] = roc_auc_score(y_true, pos_probs)
    metrics["pr_auc"] = average_precision_score(y_true, pos_probs)
    metrics["log_loss"] = log_loss(y_true, pos_probs, labels=[0,1])
    metrics["brier_score"] = brier_score_loss(y_true, pos_probs)

# Confusion matrix and detailed report
cm = confusion_matrix(y_true, y_pred, labels=[0,1])
report = classification_report(y_true, y_pred, digits=4)

print("Sklearn binary metrics:")
for k, v in metrics.items():
    print(f"{k}: {v:.4f}")
print("\nConfusion matrix:\n", cm)
print("\nClassification report:\n", report)
# Out:
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 65ms/step
# Sklearn binary metrics:
# accuracy: 0.9612
# precision: 0.7692
# recall: 0.8333
# f1: 0.8000
# mcc: 0.7793
# roc_auc: 0.9886
# pr_auc: 0.9250
# log_loss: 0.1092
# brier_score: 0.0312
#
# Confusion matrix:
#  [[114   3]
#  [  2  10]]
#
# Classification report:
#                precision    recall  f1-score   support
#
#            0     0.9828    0.9744    0.9785       117
#            1     0.7692    0.8333    0.8000        12
#
#     accuracy                         0.9612       129
#    macro avg     0.8760    0.9038    0.8893       129
# weighted avg     0.9629    0.9612    0.9619       129
