# %%
# Import packages and modules
import numpy  as np
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow_decision_forests as tfdf

from sklearn.model_selection import train_test_split
# Out:
# 2026-08-15 05:21:42.373315: I tensorflow/core/util/port.cc:113] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2026-08-15 05:21:42.739533: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2026-08-15 05:21:47.558433: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
# Check the version of TensorFlow Decision Forests
print("Found TensorFlow Decision Forests v" + tfdf.__version__)
# Out:
# Found TensorFlow Decision Forests v1.9.1

# %%
datasetPath = 'dataset/firstorder/kernel5/dataset.csv'

# %%
# Parameters
datasetPath = "dataset/glrlm/kernel6/1.dataset.csv"

# %%
# train/validation/test = 70/10/20
dataset = pd.read_csv(datasetPath)

train_data, temp_data = train_test_split(dataset, test_size=0.3, random_state=42)
validation_data, test_data = train_test_split(temp_data, test_size=2/3, random_state=42)

# %%
from sklearn.utils.class_weight import compute_class_weight

# tinh class weight tren tap train
classes = np.array([0, 1])
weights = compute_class_weight(class_weight="balanced", classes=classes, y=train_data["label"])
class_weight = {0: weights[0], 1: weights[1]}

# gan sample_weight cho tung dong
train_data["sample_weight"] = train_data["label"].map(class_weight)
validation_data["sample_weight"] = validation_data["label"].map(class_weight)
test_data["sample_weight"] = test_data["label"].map(class_weight)

# Convert the dataset into a TensorFlow dataset.
train_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    train_data, label="label", weight="sample_weight"
)         
val_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    validation_data, label="label", weight="sample_weight"
)
test_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    test_data, label="label", weight="sample_weight"
)
# Out:
# 2026-08-15 05:22:00.758734: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:984] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2026-08-15 05:22:00.760210: W tensorflow/core/common_runtime/gpu/gpu_device.cc:2251] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...

# %%
import keras

# %%
# %%time

# Train a Random Forest model.
model = tfdf.keras.RandomForestModel()

# Add evaluation metrics
model.compile(
    metrics=["accuracy"]
)
model.fit(x=train_ds)

# # Train a Gradient Boosted Trees model.
# model = tfdf.keras.GradientBoostedTreesModel(num_trees=1500)
# model.fit(train_ds)
# Out:
# Use /tmp/tmpmkn7pkt0 as temporary training directory
# Reading training dataset...
# Training dataset read in 0:00:02.609554. Found 507 examples.
# Training model...
# Model trained in 0:00:00.037360
# Compiling model...
# [INFO 26-08-15 05:22:03.5738 UTC kernel.cc:1233] Loading model from path /tmp/tmpmkn7pkt0/model/ with prefix 8a8613e7313d468f
# [INFO 26-08-15 05:22:03.5774 UTC decision_forest.cc:734] Model loaded with 300 root(s), 2198 node(s), and 16 input feature(s).
# [INFO 26-08-15 05:22:03.5774 UTC abstract_model.cc:1362] Engine "RandomForestOptPred" built
# [INFO 26-08-15 05:22:03.5775 UTC kernel.cc:1061] Use fast generic engine
# Model compiled.
# CPU times: user 5.37 s, sys: 132 ms, total: 5.5 s
# Wall time: 5.8 s

# %%
# Evaluate the model
evaluate = model.evaluate(val_ds, return_dict=True)
print()

for name, value in evaluate.items():
    print(f"{name}: {value:.4f}")
# Out:
# WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 1/1 [==============================] - ETA: 0s - loss: 0.0000e+00 - accuracy: 0.9444
# 1/1 [==============================] - 3s 3s/step - loss: 0.0000e+00 - accuracy: 0.9444
# loss: 0.0000
# accuracy: 0.9444

# %%
# Model Summary
model.summary()
# Out:
# Model: "random_forest_model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
# =================================================================
# Total params: 1 (1.00 Byte)
# Trainable params: 0 (0.00 Byte)
# Non-trainable params: 1 (1.00 Byte)
# _________________________________________________________________
# Type: "RANDOM_FOREST"
# Task: CLASSIFICATION
# Label: "__LABEL"
#
# Input Features (16):
# 	GrayLevelNonUniformity
# 	GrayLevelNonUniformityNormalized
# 	GrayLevelVariance
# 	HighGrayLevelRunEmphasis
# 	LongRunEmphasis
# 	LongRunHighGrayLevelEmphasis
# 	LongRunLowGrayLevelEmphasis
# 	LowGrayLevelRunEmphasis
# 	RunEntropy
# 	RunLengthNonUniformity
# 	RunLengthNonUniformityNormalized
# 	RunPercentage
# 	RunVariance
# 	ShortRunEmphasis
# 	ShortRunHighGrayLevelEmphasis
# 	ShortRunLowGrayLevelEmphasis
#
# Trained with weights
#
# Variable Importance: INV_MEAN_MIN_DEPTH:
#     1.    "ShortRunHighGrayLevelEmphasis"  0.400570 ################
#     2.         "HighGrayLevelRunEmphasis"  0.389071 #############
#     3.     "LongRunHighGrayLevelEmphasis"  0.368542 #########
#     4.      "LongRunLowGrayLevelEmphasis"  0.363985 ########
#     5.     "ShortRunLowGrayLevelEmphasis"  0.350151 #####
#     6.          "LowGrayLevelRunEmphasis"  0.347102 ####
#     7.                       "RunEntropy"  0.343129 ####
#     8. "GrayLevelNonUniformityNormalized"  0.339195 ###
#     9.           "GrayLevelNonUniformity"  0.338614 ###
#    10.                "GrayLevelVariance"  0.334207 ##
#    11.                    "RunPercentage"  0.328208
#    12.           "RunLengthNonUniformity"  0.327505
#    13. "RunLengthNonUniformityNormalized"  0.325297
#    14.                  "LongRunEmphasis"  0.324799
#    15.                      "RunVariance"  0.323999
#    16.                 "ShortRunEmphasis"  0.323648
#
# Variable Importance: NUM_AS_ROOT:
#     1.    "ShortRunHighGrayLevelEmphasis" 74.000000 ################
#     2.         "HighGrayLevelRunEmphasis" 67.000000 ##############
#     3.     "LongRunHighGrayLevelEmphasis" 49.000000 ##########
#     4.      "LongRunLowGrayLevelEmphasis" 42.000000 ########
#     5.     "ShortRunLowGrayLevelEmphasis" 26.000000 #####
#     6.          "LowGrayLevelRunEmphasis" 25.000000 #####
#     7.                       "RunEntropy"  6.000000 #
#     8. "GrayLevelNonUniformityNormalized"  5.000000
#     9.                "GrayLevelVariance"  3.000000
#    10.           "GrayLevelNonUniformity"  2.000000
#    11.                      "RunVariance"  1.000000
#
# Variable Importance: NUM_NODES:
#     1.    "ShortRunHighGrayLevelEmphasis" 122.000000 ################
#     2.         "HighGrayLevelRunEmphasis" 110.000000 ##############
#     3.                       "RunEntropy" 93.000000 ###########
#     4.      "LongRunLowGrayLevelEmphasis" 82.000000 ##########
#     5. "GrayLevelNonUniformityNormalized" 81.000000 #########
#     6.           "GrayLevelNonUniformity" 80.000000 #########
#     7.     "LongRunHighGrayLevelEmphasis" 78.000000 #########
#     8.     "ShortRunLowGrayLevelEmphasis" 62.000000 #######
#     9.          "LowGrayLevelRunEmphasis" 61.000000 #######
#    10.                "GrayLevelVariance" 52.000000 #####
#    11.                    "RunPercentage" 33.000000 ##
#    12.           "RunLengthNonUniformity" 28.000000 ##
#    13.                  "LongRunEmphasis" 20.000000 #
#    14. "RunLengthNonUniformityNormalized" 17.000000
#    15.                 "ShortRunEmphasis" 17.000000
#    16.                      "RunVariance" 13.000000
#
# Variable Importance: SUM_SCORE:
#     1.    "ShortRunHighGrayLevelEmphasis" 21968.541374 ################
#     2.         "HighGrayLevelRunEmphasis" 20054.651850 ##############
#     3.     "LongRunHighGrayLevelEmphasis" 13697.765821 #########
#     4.      "LongRunLowGrayLevelEmphasis" 12020.581293 ########
#     5.          "LowGrayLevelRunEmphasis" 7388.851634 #####
#     6.     "ShortRunLowGrayLevelEmphasis" 7268.460997 #####
#     7. "GrayLevelNonUniformityNormalized" 4620.484104 ###
#     8.           "GrayLevelNonUniformity" 4576.934688 ###
#     9.                       "RunEntropy" 4387.527190 ###
#    10.                "GrayLevelVariance" 1902.160058 #
#    11.                    "RunPercentage" 1003.971804
#    12.           "RunLengthNonUniformity" 840.319305
#    13. "RunLengthNonUniformityNormalized" 434.946264
#    14.                  "LongRunEmphasis" 414.460950
#    15.                      "RunVariance" 369.789101
#    16.                 "ShortRunEmphasis" 289.093312
#
#
#
# Winner takes all: true
# Out-of-bag evaluation: accuracy:0.939236 logloss:0.0892827
# Number of trees: 300
# Total number of nodes: 2198
#
# Number of nodes by tree:
# Count: 300 Average: 7.32667 StdDev: 1.96976
# Min: 3 Max: 15 Ignored: 0
# ----------------------------------------------
# [  3,  4)   8   2.67%   2.67% #
# [  4,  5)   0   0.00%   2.67%
# [  5,  6)  66  22.00%  24.67% #####
# [  6,  7)   0   0.00%  24.67%
# [  7,  8) 124  41.33%  66.00% ##########
# [  8,  9)   0   0.00%  66.00%
# [  9, 10)  78  26.00%  92.00% ######
# [ 10, 11)   0   0.00%  92.00%
# [ 11, 12)  20   6.67%  98.67% ##
# [ 12, 13)   0   0.00%  98.67%
# [ 13, 14)   3   1.00%  99.67%
# [ 14, 15)   0   0.00%  99.67%
# [ 15, 15]   1   0.33% 100.00%
#
# Depth by leafs:
# Count: 1249 Average: 2.22098 StdDev: 0.727483
# Min: 1 Max: 5 Ignored: 0
# ----------------------------------------------
# [ 1, 2) 136  10.89%  10.89% ##
# [ 2, 3) 782  62.61%  73.50% ##########
# [ 3, 4) 256  20.50%  94.00% ###
# [ 4, 5)  69   5.52%  99.52% #
# [ 5, 5]   6   0.48% 100.00%
#
# Number of training obs by leaf:
# Count: 1249 Average: 121.777 StdDev: 191.388
# Min: 5 Max: 492 Ignored: 0
# ----------------------------------------------
# [   5,  29) 870  69.66%  69.66% ##########
# [  29,  53)  50   4.00%  73.66% #
# [  53,  78)  16   1.28%  74.94%
# [  78, 102)   3   0.24%  75.18%
# [ 102, 127)   2   0.16%  75.34%
# [ 127, 151)   3   0.24%  75.58%
# [ 151, 175)   0   0.00%  75.58%
# [ 175, 200)   1   0.08%  75.66%
# [ 200, 224)   2   0.16%  75.82%
# [ 224, 249)   4   0.32%  76.14%
# [ 249, 273)   2   0.16%  76.30%
# [ 273, 297)   2   0.16%  76.46%
# [ 297, 322)   1   0.08%  76.54%
# [ 322, 346)   3   0.24%  76.78%
# [ 346, 371)   0   0.00%  76.78%
# [ 371, 395)   3   0.24%  77.02%
# [ 395, 419)  16   1.28%  78.30%
# [ 419, 444)   9   0.72%  79.02%
# [ 444, 468)  85   6.81%  85.83% #
# [ 468, 492] 177  14.17% 100.00% ##
#
# Attribute in nodes:
# 	122 : ShortRunHighGrayLevelEmphasis [NUMERICAL]
# 	110 : HighGrayLevelRunEmphasis [NUMERICAL]
# 	93 : RunEntropy [NUMERICAL]
# 	82 : LongRunLowGrayLevelEmphasis [NUMERICAL]
# 	81 : GrayLevelNonUniformityNormalized [NUMERICAL]
# 	80 : GrayLevelNonUniformity [NUMERICAL]
# 	78 : LongRunHighGrayLevelEmphasis [NUMERICAL]
# 	62 : ShortRunLowGrayLevelEmphasis [NUMERICAL]
# 	61 : LowGrayLevelRunEmphasis [NUMERICAL]
# 	52 : GrayLevelVariance [NUMERICAL]
# 	33 : RunPercentage [NUMERICAL]
# 	28 : RunLengthNonUniformity [NUMERICAL]
# 	20 : LongRunEmphasis [NUMERICAL]
# 	17 : ShortRunEmphasis [NUMERICAL]
# 	17 : RunLengthNonUniformityNormalized [NUMERICAL]
# 	13 : RunVariance [NUMERICAL]
#
# Attribute in nodes with depth <= 0:
# 	74 : ShortRunHighGrayLevelEmphasis [NUMERICAL]
# 	67 : HighGrayLevelRunEmphasis [NUMERICAL]
# 	49 : LongRunHighGrayLevelEmphasis [NUMERICAL]
# 	42 : LongRunLowGrayLevelEmphasis [NUMERICAL]
# 	26 : ShortRunLowGrayLevelEmphasis [NUMERICAL]
# 	25 : LowGrayLevelRunEmphasis [NUMERICAL]
# 	6 : RunEntropy [NUMERICAL]
# 	5 : GrayLevelNonUniformityNormalized [NUMERICAL]
# 	3 : GrayLevelVariance [NUMERICAL]
# 	2 : GrayLevelNonUniformity [NUMERICAL]
# 	1 : RunVariance [NUMERICAL]
#
# Attribute in nodes with depth <= 1:
# 	112 : ShortRunHighGrayLevelEmphasis [NUMERICAL]
# 	98 : HighGrayLevelRunEmphasis [NUMERICAL]
# 	70 : LongRunLowGrayLevelEmphasis [NUMERICAL]
# 	68 : LongRunHighGrayLevelEmphasis [NUMERICAL]
# 	64 : RunEntropy [NUMERICAL]
# 	64 : GrayLevelNonUniformity [NUMERICAL]
# 	62 : GrayLevelNonUniformityNormalized [NUMERICAL]
# 	53 : ShortRunLowGrayLevelEmphasis [NUMERICAL]
# 	49 : LowGrayLevelRunEmphasis [NUMERICAL]
# 	27 : GrayLevelVariance [NUMERICAL]
# 	24 : RunLengthNonUniformity [NUMERICAL]
# 	22 : RunPercentage [NUMERICAL]
# 	15 : ShortRunEmphasis [NUMERICAL]
# 	14 : LongRunEmphasis [NUMERICAL]
# 	13 : RunLengthNonUniformityNormalized [NUMERICAL]
# 	9 : RunVariance [NUMERICAL]
#
# Attribute in nodes with depth <= 2:
# 	121 : ShortRunHighGrayLevelEmphasis [NUMERICAL]
# 	107 : HighGrayLevelRunEmphasis [NUMERICAL]
# 	86 : RunEntropy [NUMERICAL]
# 	79 : LongRunLowGrayLevelEmphasis [NUMERICAL]
# 	79 : GrayLevelNonUniformityNormalized [NUMERICAL]
# 	75 : LongRunHighGrayLevelEmphasis [NUMERICAL]
# 	74 : GrayLevelNonUniformity [NUMERICAL]
# 	59 : ShortRunLowGrayLevelEmphasis [NUMERICAL]
# 	59 : LowGrayLevelRunEmphasis [NUMERICAL]
# 	48 : GrayLevelVariance [NUMERICAL]
# 	33 : RunPercentage [NUMERICAL]
# 	27 : RunLengthNonUniformity [NUMERICAL]
# 	18 : LongRunEmphasis [NUMERICAL]
# 	17 : ShortRunEmphasis [NUMERICAL]
# 	16 : RunLengthNonUniformityNormalized [NUMERICAL]
# 	12 : RunVariance [NUMERICAL]
#
# Attribute in nodes with depth <= 3:
# 	122 : ShortRunHighGrayLevelEmphasis [NUMERICAL]
# 	110 : HighGrayLevelRunEmphasis [NUMERICAL]
# 	92 : RunEntropy [NUMERICAL]
# 	81 : LongRunLowGrayLevelEmphasis [NUMERICAL]
# 	80 : GrayLevelNonUniformityNormalized [NUMERICAL]
# 	80 : GrayLevelNonUniformity [NUMERICAL]
# 	78 : LongRunHighGrayLevelEmphasis [NUMERICAL]
# 	62 : ShortRunLowGrayLevelEmphasis [NUMERICAL]
# 	61 : LowGrayLevelRunEmphasis [NUMERICAL]
# 	52 : GrayLevelVariance [NUMERICAL]
# 	33 : RunPercentage [NUMERICAL]
# 	28 : RunLengthNonUniformity [NUMERICAL]
# 	20 : LongRunEmphasis [NUMERICAL]
# 	17 : ShortRunEmphasis [NUMERICAL]
# 	17 : RunLengthNonUniformityNormalized [NUMERICAL]
# 	13 : RunVariance [NUMERICAL]
#
# Attribute in nodes with depth <= 5:
# 	122 : ShortRunHighGrayLevelEmphasis [NUMERICAL]
# 	110 : HighGrayLevelRunEmphasis [NUMERICAL]
# 	93 : RunEntropy [NUMERICAL]
# 	82 : LongRunLowGrayLevelEmphasis [NUMERICAL]
# 	81 : GrayLevelNonUniformityNormalized [NUMERICAL]
# 	80 : GrayLevelNonUniformity [NUMERICAL]
# 	78 : LongRunHighGrayLevelEmphasis [NUMERICAL]
# 	62 : ShortRunLowGrayLevelEmphasis [NUMERICAL]
# 	61 : LowGrayLevelRunEmphasis [NUMERICAL]
# 	52 : GrayLevelVariance [NUMERICAL]
# 	33 : RunPercentage [NUMERICAL]
# 	28 : RunLengthNonUniformity [NUMERICAL]
# 	20 : LongRunEmphasis [NUMERICAL]
# 	17 : ShortRunEmphasis [NUMERICAL]
# 	17 : RunLengthNonUniformityNormalized [NUMERICAL]
# 	13 : RunVariance [NUMERICAL]
#
# Condition type in nodes:
# 	949 : HigherCondition
# Condition type in nodes with depth <= 0:
# 	300 : HigherCondition
# Condition type in nodes with depth <= 1:
# 	764 : HigherCondition
# Condition type in nodes with depth <= 2:
# 	910 : HigherCondition
# Condition type in nodes with depth <= 3:
# 	946 : HigherCondition
# Condition type in nodes with depth <= 5:
# 	949 : HigherCondition
# Node format: NOT_SET
#
# Training OOB:
# 	trees: 1, Out-of-bag evaluation: accuracy:0.915567 logloss:3.04326
# 	trees: 11, Out-of-bag evaluation: accuracy:0.87135 logloss:3.17275
# 	trees: 21, Out-of-bag evaluation: accuracy:0.92272 logloss:0.121728
# 	trees: 31, Out-of-bag evaluation: accuracy:0.958796 logloss:0.0924312
# 	trees: 41, Out-of-bag evaluation: accuracy:0.940278 logloss:0.0871235
# 	trees: 51, Out-of-bag evaluation: accuracy:0.941319 logloss:0.0857393
# 	trees: 63, Out-of-bag evaluation: accuracy:0.941319 logloss:0.0904575
# 	trees: 73, Out-of-bag evaluation: accuracy:0.941319 logloss:0.0892302
# 	trees: 83, Out-of-bag evaluation: accuracy:0.941319 logloss:0.089278
# 	trees: 93, Out-of-bag evaluation: accuracy:0.941319 logloss:0.0947472
# 	trees: 103, Out-of-bag evaluation: accuracy:0.941319 logloss:0.0970924
# 	trees: 114, Out-of-bag evaluation: accuracy:0.941319 logloss:0.0954399
# 	trees: 125, Out-of-bag evaluation: accuracy:0.940278 logloss:0.0958021
# 	trees: 135, Out-of-bag evaluation: accuracy:0.939236 logloss:0.0949668
# 	trees: 145, Out-of-bag evaluation: accuracy:0.939236 logloss:0.0960101
# 	trees: 155, Out-of-bag evaluation: accuracy:0.939236 logloss:0.0950137
# 	trees: 165, Out-of-bag evaluation: accuracy:0.939236 logloss:0.0944009
# 	trees: 176, Out-of-bag evaluation: accuracy:0.939236 logloss:0.0927894
# 	trees: 186, Out-of-bag evaluation: accuracy:0.939236 logloss:0.0941549
# 	trees: 196, Out-of-bag evaluation: accuracy:0.939236 logloss:0.0900745
# 	trees: 206, Out-of-bag evaluation: accuracy:0.939236 logloss:0.0903852
# 	trees: 217, Out-of-bag evaluation: accuracy:0.939236 logloss:0.089766
# 	trees: 227, Out-of-bag evaluation: accuracy:0.939236 logloss:0.0899157
# 	trees: 237, Out-of-bag evaluation: accuracy:0.939236 logloss:0.08826
# 	trees: 248, Out-of-bag evaluation: accuracy:0.939236 logloss:0.089435
# 	trees: 258, Out-of-bag evaluation: accuracy:0.939236 logloss:0.08906
# 	trees: 269, Out-of-bag evaluation: accuracy:0.939236 logloss:0.0886478
# 	trees: 281, Out-of-bag evaluation: accuracy:0.939236 logloss:0.0889028
# 	trees: 291, Out-of-bag evaluation: accuracy:0.939236 logloss:0.0889905
# 	trees: 300, Out-of-bag evaluation: accuracy:0.939236 logloss:0.0892827

# %%
# Model features
model.make_inspector().features()
# Out:
# ["GrayLevelNonUniformity" (1; #0),
#  "GrayLevelNonUniformityNormalized" (1; #1),
#  "GrayLevelVariance" (1; #2),
#  "HighGrayLevelRunEmphasis" (1; #3),
#  "LongRunEmphasis" (1; #4),
#  "LongRunHighGrayLevelEmphasis" (1; #5),
#  "LongRunLowGrayLevelEmphasis" (1; #6),
#  "LowGrayLevelRunEmphasis" (1; #7),
#  "RunEntropy" (1; #8),
#  "RunLengthNonUniformity" (1; #9),
#  "RunLengthNonUniformityNormalized" (1; #10),
#  "RunPercentage" (1; #11),
#  "RunVariance" (1; #12),
#  "ShortRunEmphasis" (1; #13),
#  "ShortRunHighGrayLevelEmphasis" (1; #14),
#  "ShortRunLowGrayLevelEmphasis" (1; #15)]

# %%
# Feature importance
model.make_inspector().variable_importances()
# Out:
# {'INV_MEAN_MIN_DEPTH': [("ShortRunHighGrayLevelEmphasis" (1; #14),
#    0.40057033585915214),
#   ("HighGrayLevelRunEmphasis" (1; #3), 0.38907081552022016),
#   ("LongRunHighGrayLevelEmphasis" (1; #5), 0.3685417446649197),
#   ("LongRunLowGrayLevelEmphasis" (1; #6), 0.36398459131896777),
#   ("ShortRunLowGrayLevelEmphasis" (1; #15), 0.3501507593547224),
#   ("LowGrayLevelRunEmphasis" (1; #7), 0.3471021788926065),
#   ("RunEntropy" (1; #8), 0.34312884488125306),
#   ("GrayLevelNonUniformityNormalized" (1; #1), 0.33919521896262816),
#   ("GrayLevelNonUniformity" (1; #0), 0.3386136458611876),
#   ("GrayLevelVariance" (1; #2), 0.3342073119785473),
#   ("RunPercentage" (1; #11), 0.3282079066847618),
#   ("RunLengthNonUniformity" (1; #9), 0.3275053836946509),
#   ("RunLengthNonUniformityNormalized" (1; #10), 0.3252968656614308),
#   ("LongRunEmphasis" (1; #4), 0.3247987729824134),
#   ("RunVariance" (1; #12), 0.32399949085794316),
#   ("ShortRunEmphasis" (1; #13), 0.323648286783206)],
#  'NUM_AS_ROOT': [("ShortRunHighGrayLevelEmphasis" (1; #14), 74.0),
#   ("HighGrayLevelRunEmphasis" (1; #3), 67.0),
#   ("LongRunHighGrayLevelEmphasis" (1; #5), 49.0),
#   ("LongRunLowGrayLevelEmphasis" (1; #6), 42.0),
#   ("ShortRunLowGrayLevelEmphasis" (1; #15), 26.0),
#   ("LowGrayLevelRunEmphasis" (1; #7), 25.0),
#   ("RunEntropy" (1; #8), 6.0),
#   ("GrayLevelNonUniformityNormalized" (1; #1), 5.0),
#   ("GrayLevelVariance" (1; #2), 3.0),
#   ("GrayLevelNonUniformity" (1; #0), 2.0),
#   ("RunVariance" (1; #12), 1.0)],
#  'SUM_SCORE': [("ShortRunHighGrayLevelEmphasis" (1; #14), 21968.541373802153),
#   ("HighGrayLevelRunEmphasis" (1; #3), 20054.651850406815),
#   ("LongRunHighGrayLevelEmphasis" (1; #5), 13697.76582113004),
#   ("LongRunLowGrayLevelEmphasis" (1; #6), 12020.581293366231),
#   ("LowGrayLevelRunEmphasis" (1; #7), 7388.851634437068),
#   ("ShortRunLowGrayLevelEmphasis" (1; #15), 7268.460997336648),
#   ("GrayLevelNonUniformityNormalized" (1; #1), 4620.48410376917),
#   ("GrayLevelNonUniformity" (1; #0), 4576.934687609538),
#   ("RunEntropy" (1; #8), 4387.527189777878),
#   ("GrayLevelVariance" (1; #2), 1902.1600575987204),
#   ("RunPercentage" (1; #11), 1003.9718036138556),
#   ("RunLengthNonUniformity" (1; #9), 840.3193047232329),
#   ("RunLengthNonUniformityNormalized" (1; #10), 434.94626414141385),
#   ("LongRunEmphasis" (1; #4), 414.46094965323346),
#   ("RunVariance" (1; #12), 369.78910143689416),
#   ("ShortRunEmphasis" (1; #13), 289.0933121333054)],
#  'NUM_NODES': [("ShortRunHighGrayLevelEmphasis" (1; #14), 122.0),
#   ("HighGrayLevelRunEmphasis" (1; #3), 110.0),
#   ("RunEntropy" (1; #8), 93.0),
#   ("LongRunLowGrayLevelEmphasis" (1; #6), 82.0),
#   ("GrayLevelNonUniformityNormalized" (1; #1), 81.0),
#   ("GrayLevelNonUniformity" (1; #0), 80.0),
#   ("LongRunHighGrayLevelEmphasis" (1; #5), 78.0),
#   ("ShortRunLowGrayLevelEmphasis" (1; #15), 62.0),
#   ("LowGrayLevelRunEmphasis" (1; #7), 61.0),
#   ("GrayLevelVariance" (1; #2), 52.0),
#   ("RunPercentage" (1; #11), 33.0),
#   ("RunLengthNonUniformity" (1; #9), 28.0),
#   ("LongRunEmphasis" (1; #4), 20.0),
#   ("RunLengthNonUniformityNormalized" (1; #10), 17.0),
#   ("ShortRunEmphasis" (1; #13), 17.0),
#   ("RunVariance" (1; #12), 13.0)]}

# %%
# Model self evaluation
model.make_inspector().evaluation()
# Out:
# Evaluation(num_examples=507, accuracy=0.9392361094064418, loss=0.08928268344882376, rmse=None, ndcg=None, aucs=None, auuc=None, qini=None)

# %%
logs = model.make_inspector().training_logs()

plt.figure(figsize=(12, 4))
plt.subplot(1, 2, 1)
plt.plot([log.num_trees for log in logs], [log.evaluation.accuracy for log in logs])
plt.xlabel("Number of trees")
plt.ylabel("Accuracy (out-of-bag)")
plt.subplot(1, 2, 2)
plt.plot([log.num_trees for log in logs], [log.evaluation.loss for log in logs])
plt.xlabel("Number of trees")
plt.ylabel("Logloss (out-of-bag)")
plt.show()

# %% [markdown]
# Calculate the score of our hold-out validation dataset

# %%
predictions = model.predict(val_ds)
y_true      = validation_data["label"]

from sklearn.metrics import roc_auc_score
ROC_AUC = roc_auc_score(y_true, predictions)
print("The ROC AUC score is %.5f" % ROC_AUC )
# Out:
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 58ms/step
# The ROC AUC score is 0.99517

# %%
# Compute binary classification metrics with sklearn
import numpy as np
from sklearn.metrics import (
    accuracy_score,
    precision_score,
    recall_score,
    f1_score,
    roc_auc_score,
    average_precision_score,
    confusion_matrix,
    classification_report,
    matthews_corrcoef,
    log_loss,
    brier_score_loss,
)

# Get predictions (probabilities or class labels)
preds = model.predict(test_ds)
# If model outputs probabilities, convert to labels by threshold 0.5
if preds.ndim == 2:
    # For TFDF classification, preds may be class probabilities with shape (N, 2)
    if preds.shape[1] == 2:
        pos_probs = preds[:, 1]
    else:
        # If single-probability column (positive class)
        pos_probs = preds[:, -1]
    y_pred = (pos_probs >= 0.5).astype(int)
else:
    # Already class labels
    y_pred = preds.astype(int)
    pos_probs = None

# Ground truth labels (must be 0/1 integers)
y_true = test_data["label"].astype(int).to_numpy()

# Core metrics
metrics = {}
metrics["accuracy"] = accuracy_score(y_true, y_pred)
metrics["precision"] = precision_score(y_true, y_pred, zero_division=0)
metrics["recall"] = recall_score(y_true, y_pred, zero_division=0)
metrics["f1"] = f1_score(y_true, y_pred, zero_division=0)
metrics["mcc"] = matthews_corrcoef(y_true, y_pred)

# Probabilistic metrics (only if we have probabilities)
if pos_probs is not None:
    metrics["roc_auc"] = roc_auc_score(y_true, pos_probs)
    metrics["pr_auc"] = average_precision_score(y_true, pos_probs)
    metrics["log_loss"] = log_loss(y_true, pos_probs, labels=[0,1])
    metrics["brier_score"] = brier_score_loss(y_true, pos_probs)

# Confusion matrix and detailed report
cm = confusion_matrix(y_true, y_pred, labels=[0,1])
report = classification_report(y_true, y_pred, digits=4)

print("Sklearn binary metrics:")
for k, v in metrics.items():
    print(f"{k}: {v:.4f}")
print("\nConfusion matrix:\n", cm)
print("\nClassification report:\n", report)
# Out:
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 67ms/step
# Sklearn binary metrics:
# accuracy: 0.9726
# precision: 0.8750
# recall: 0.7000
# f1: 0.7778
# mcc: 0.7688
# roc_auc: 0.9846
# pr_auc: 0.8369
# log_loss: 0.0834
# brier_score: 0.0255
#
# Confusion matrix:
#  [[135   1]
#  [  3   7]]
#
# Classification report:
#                precision    recall  f1-score   support
#
#            0     0.9783    0.9926    0.9854       136
#            1     0.8750    0.7000    0.7778        10
#
#     accuracy                         0.9726       146
#    macro avg     0.9266    0.8463    0.8816       146
# weighted avg     0.9712    0.9726    0.9712       146
