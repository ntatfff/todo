# %%
# Import packages and modules
import numpy  as np
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow_decision_forests as tfdf

from sklearn.model_selection import train_test_split
# Out:
# 2026-08-10 17:16:43.595795: I tensorflow/core/util/port.cc:113] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2026-08-10 17:16:43.951156: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2026-08-10 17:16:48.727263: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
# Check the version of TensorFlow Decision Forests
print("Found TensorFlow Decision Forests v" + tfdf.__version__)
# Out:
# Found TensorFlow Decision Forests v1.9.1

# %%
datasetPath = 'dataset/firstorder/kernel5-radius5/dataset.csv'

# %%
# Parameters
datasetPath = "dataset/glszm/kernel6-radius6/dataset.1p.csv"

# %%
# train/validation/test = 70/10/20
dataset = pd.read_csv(datasetPath)

train_data, temp_data = train_test_split(dataset, test_size=0.3, random_state=42)
validation_data, test_data = train_test_split(temp_data, test_size=2/3, random_state=42)

# %%
from sklearn.utils.class_weight import compute_class_weight

# tinh class weight tren tap train
classes = np.array([0, 1])
weights = compute_class_weight(class_weight="balanced", classes=classes, y=train_data["label"])
class_weight = {0: weights[0], 1: weights[1]}

# gan sample_weight cho tung dong
train_data["sample_weight"] = train_data["label"].map(class_weight)
validation_data["sample_weight"] = validation_data["label"].map(class_weight)
test_data["sample_weight"] = test_data["label"].map(class_weight)

# Convert the dataset into a TensorFlow dataset.
train_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    train_data, label="label", weight="sample_weight"
)         
val_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    validation_data, label="label", weight="sample_weight"
)
test_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    test_data, label="label", weight="sample_weight"
)
# Out:
# 2026-08-10 17:17:04.823125: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:984] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2026-08-10 17:17:04.824320: W tensorflow/core/common_runtime/gpu/gpu_device.cc:2251] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...

# %%
import keras

# %%
# %%time

# Train a Gradient Boosted Trees model.
model = tfdf.keras.GradientBoostedTreesModel()

# Add evaluation metrics
model.compile(
    metrics=["accuracy"]
)
model.fit(x=train_ds)

# # Train a Gradient Boosted Trees model.
# model = tfdf.keras.GradientBoostedTreesModel(num_trees=1500)
# model.fit(train_ds)
# Out:
# Use /tmp/tmp2wb2s6a8 as temporary training directory
# [WARNING 26-08-10 17:17:05.0181 UTC gradient_boosted_trees.cc:1840] "goss_alpha" set but "sampling_method" not equal to "GOSS".
# [WARNING 26-08-10 17:17:05.0183 UTC gradient_boosted_trees.cc:1851] "goss_beta" set but "sampling_method" not equal to "GOSS".
# [WARNING 26-08-10 17:17:05.0183 UTC gradient_boosted_trees.cc:1865] "selective_gradient_boosting_ratio" set but "sampling_method" not equal to "SELGB".
# Reading training dataset...
# Training dataset read in 0:00:02.799140. Found 777 examples.
# Training model...
# Model trained in 0:00:01.172890
# Compiling model...
# [INFO 26-08-10 17:17:09.0187 UTC kernel.cc:1233] Loading model from path /tmp/tmp2wb2s6a8/model/ with prefix 75275e7cffd84d60
# [INFO 26-08-10 17:17:09.0256 UTC quick_scorer_extended.cc:911] The binary was compiled without AVX2 support, but your CPU supports it. Enable it for faster model inference.
# [INFO 26-08-10 17:17:09.0261 UTC abstract_model.cc:1362] Engine "GradientBoostedTreesQuickScorerExtended" built
# [INFO 26-08-10 17:17:09.0261 UTC kernel.cc:1061] Use fast generic engine
# Model compiled.
# CPU times: user 7.35 s, sys: 1.6 s, total: 8.94 s
# Wall time: 7.09 s

# %%
# Evaluate the model
evaluate = model.evaluate(val_ds, return_dict=True)
print()

for name, value in evaluate.items():
    print(f"{name}: {value:.4f}")
# Out:
# WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 1/1 [==============================] - ETA: 0s - loss: 0.0000e+00 - accuracy: 1.0000
# 1/1 [==============================] - 3s 3s/step - loss: 0.0000e+00 - accuracy: 1.0000
# loss: 0.0000
# accuracy: 1.0000

# %%
# Model Summary
model.summary()
# Out:
# Model: "gradient_boosted_trees_model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
# =================================================================
# Total params: 1 (1.00 Byte)
# Trainable params: 0 (0.00 Byte)
# Non-trainable params: 1 (1.00 Byte)
# _________________________________________________________________
# Type: "GRADIENT_BOOSTED_TREES"
# Task: CLASSIFICATION
# Label: "__LABEL"
#
# Input Features (34):
# 	10Percentile
# 	90Percentile
# 	Energy
# 	Entropy
# 	GrayLevelNonUniformity
# 	GrayLevelNonUniformityNormalized
# 	GrayLevelVariance
# 	HighGrayLevelZoneEmphasis
# 	InterquartileRange
# 	Kurtosis
# 	LargeAreaEmphasis
# 	LargeAreaHighGrayLevelEmphasis
# 	LargeAreaLowGrayLevelEmphasis
# 	LowGrayLevelZoneEmphasis
# 	Maximum
# 	Mean
# 	MeanAbsoluteDeviation
# 	Median
# 	Minimum
# 	Range
# 	RobustMeanAbsoluteDeviation
# 	RootMeanSquared
# 	SizeZoneNonUniformity
# 	SizeZoneNonUniformityNormalized
# 	Skewness
# 	SmallAreaEmphasis
# 	SmallAreaHighGrayLevelEmphasis
# 	SmallAreaLowGrayLevelEmphasis
# 	TotalEnergy
# 	Uniformity
# 	Variance
# 	ZoneEntropy
# 	ZonePercentage
# 	ZoneVariance
#
# Trained with weights
#
# Variable Importance: INV_MEAN_MIN_DEPTH:
#     1.           "GrayLevelNonUniformity"  0.312712 ################
#     2.  "SizeZoneNonUniformityNormalized"  0.300273 #############
#     3.                "SmallAreaEmphasis"  0.293966 ############
#     4.    "LargeAreaLowGrayLevelEmphasis"  0.290096 ############
#     5.                         "Skewness"  0.269513 ########
#     6.         "LowGrayLevelZoneEmphasis"  0.247704 #####
#     7.   "LargeAreaHighGrayLevelEmphasis"  0.228800 ##
#     8.                "GrayLevelVariance"  0.223568 #
#     9.        "HighGrayLevelZoneEmphasis"  0.222039
#    10.                         "Variance"  0.221579
#    11.                            "Range"  0.220604
#    12.               "InterquartileRange"  0.220503
#    13.            "SizeZoneNonUniformity"  0.219704
#    14.                   "ZonePercentage"  0.219642
#    15.   "SmallAreaHighGrayLevelEmphasis"  0.219465
#    16.                          "Entropy"  0.218996
#    17.                      "TotalEnergy"  0.218711
#    18.                           "Energy"  0.218503
#    19.                "LargeAreaEmphasis"  0.218392
#    20.                  "RootMeanSquared"  0.217984
#    21.    "SmallAreaLowGrayLevelEmphasis"  0.217899
#    22. "GrayLevelNonUniformityNormalized"  0.217874
#    23.                             "Mean"  0.217675
#    24.                     "ZoneVariance"  0.217386
#    25.      "RobustMeanAbsoluteDeviation"  0.217364
#    26.                         "Kurtosis"  0.217262
#    27.                      "ZoneEntropy"  0.217185
#    28.                          "Maximum"  0.217173
#    29.                           "Median"  0.217154
#    30.                       "Uniformity"  0.217130
#    31.                          "Minimum"  0.216958
#    32.                     "90Percentile"  0.216857
#    33.                     "10Percentile"  0.216827
#    34.            "MeanAbsoluteDeviation"  0.216754
#
# Variable Importance: NUM_AS_ROOT:
#     1.   "LargeAreaLowGrayLevelEmphasis" 102.000000 ################
#     2. "SizeZoneNonUniformityNormalized" 92.000000 ##############
#     3.               "SmallAreaEmphasis" 83.000000 ############
#     4.  "LargeAreaHighGrayLevelEmphasis"  7.000000
#     5.                        "Variance"  6.000000
#     6.              "InterquartileRange"  3.000000
#     7.                          "Energy"  2.000000
#     8.                     "TotalEnergy"  1.000000
#
# Variable Importance: NUM_NODES:
#     1.    "LargeAreaLowGrayLevelEmphasis" 318.000000 ################
#     2.  "SizeZoneNonUniformityNormalized" 251.000000 ############
#     3.                "SmallAreaEmphasis" 251.000000 ############
#     4.           "GrayLevelNonUniformity" 249.000000 ############
#     5.         "LowGrayLevelZoneEmphasis" 246.000000 ############
#     6.                         "Skewness" 240.000000 ############
#     7.                "GrayLevelVariance" 198.000000 #########
#     8.        "HighGrayLevelZoneEmphasis" 164.000000 ########
#     9.   "LargeAreaHighGrayLevelEmphasis" 89.000000 ####
#    10.                   "ZonePercentage" 86.000000 ####
#    11.                          "Entropy" 64.000000 ###
#    12.   "SmallAreaHighGrayLevelEmphasis" 64.000000 ###
#    13.                            "Range" 60.000000 ##
#    14.            "SizeZoneNonUniformity" 58.000000 ##
#    15.                "LargeAreaEmphasis" 46.000000 ##
#    16.               "InterquartileRange" 32.000000 #
#    17.    "SmallAreaLowGrayLevelEmphasis" 32.000000 #
#    18.                      "TotalEnergy" 31.000000 #
#    19.                         "Variance" 30.000000 #
#    20.                  "RootMeanSquared" 29.000000 #
#    21. "GrayLevelNonUniformityNormalized" 26.000000 #
#    22.                          "Maximum" 23.000000
#    23.                         "Kurtosis" 22.000000
#    24.                      "ZoneEntropy" 22.000000
#    25.      "RobustMeanAbsoluteDeviation" 19.000000
#    26.                     "ZoneVariance" 19.000000
#    27.                           "Energy" 18.000000
#    28.                       "Uniformity" 16.000000
#    29.                           "Median" 12.000000
#    30.                     "10Percentile"  9.000000
#    31.                             "Mean"  9.000000
#    32.                          "Minimum"  8.000000
#    33.                     "90Percentile"  7.000000
#    34.            "MeanAbsoluteDeviation"  4.000000
#
# Variable Importance: SUM_SCORE:
#     1.    "LargeAreaLowGrayLevelEmphasis" 952.848722 ################
#     2.   "LargeAreaHighGrayLevelEmphasis"  0.000004
#     3.                         "Variance"  0.000001
#     4.  "SizeZoneNonUniformityNormalized"  0.000001
#     5.           "GrayLevelNonUniformity"  0.000001
#     6.                "SmallAreaEmphasis"  0.000001
#     7.                         "Skewness"  0.000000
#     8.         "LowGrayLevelZoneEmphasis"  0.000000
#     9.               "InterquartileRange"  0.000000
#    10.                            "Range"  0.000000
#    11.                           "Energy"  0.000000
#    12.                             "Mean"  0.000000
#    13.                "LargeAreaEmphasis"  0.000000
#    14.                      "TotalEnergy"  0.000000
#    15.   "SmallAreaHighGrayLevelEmphasis"  0.000000
#    16.        "HighGrayLevelZoneEmphasis"  0.000000
#    17.            "SizeZoneNonUniformity"  0.000000
#    18.                          "Entropy"  0.000000
#    19.                  "RootMeanSquared"  0.000000
#    20.                "GrayLevelVariance"  0.000000
#    21.                   "ZonePercentage"  0.000000
#    22.                         "Kurtosis"  0.000000
#    23.    "SmallAreaLowGrayLevelEmphasis"  0.000000
#    24.                          "Maximum"  0.000000
#    25.                     "ZoneVariance"  0.000000
#    26.                       "Uniformity"  0.000000
#    27.                      "ZoneEntropy"  0.000000
#    28. "GrayLevelNonUniformityNormalized"  0.000000
#    29.                           "Median"  0.000000
#    30.      "RobustMeanAbsoluteDeviation"  0.000000
#    31.                          "Minimum"  0.000000
#    32.            "MeanAbsoluteDeviation"  0.000000
#    33.                     "90Percentile"  0.000000
#    34.                     "10Percentile"  0.000000
#
#
#
# Loss: BINOMIAL_LOG_LIKELIHOOD
# Validation loss value: 9.84372e-07
# Number of trees per iteration: 1
# Node format: NOT_SET
# Number of trees: 296
# Total number of nodes: 5800
#
# Number of nodes by tree:
# Count: 296 Average: 19.5946 StdDev: 7.92689
# Min: 7 Max: 45 Ignored: 0
# ----------------------------------------------
# [  7,  8)   1   0.34%   0.34%
# [  8, 10)   4   1.35%   1.69%
# [ 10, 12)  16   5.41%   7.09% #
# [ 12, 14)  29   9.80%  16.89% ###
# [ 14, 16)  20   6.76%  23.65% ##
# [ 16, 18) 111  37.50%  61.15% ##########
# [ 18, 20)  61  20.61%  81.76% #####
# [ 20, 22)   1   0.34%  82.09%
# [ 22, 24)   8   2.70%  84.80% #
# [ 24, 26)   0   0.00%  84.80%
# [ 26, 28)   3   1.01%  85.81%
# [ 28, 30)   4   1.35%  87.16%
# [ 30, 32)   4   1.35%  88.51%
# [ 32, 34)   1   0.34%  88.85%
# [ 34, 36)   2   0.68%  89.53%
# [ 36, 38)   7   2.36%  91.89% #
# [ 38, 40)   9   3.04%  94.93% #
# [ 40, 42)  14   4.73%  99.66% #
# [ 42, 44)   0   0.00%  99.66%
# [ 44, 45]   1   0.34% 100.00%
#
# Depth by leafs:
# Count: 3048 Average: 3.79462 StdDev: 1.12701
# Min: 1 Max: 5 Ignored: 0
# ----------------------------------------------
# [ 1, 2)    4   0.13%   0.13%
# [ 2, 3)  417  13.68%  13.81% ###
# [ 3, 4) 1038  34.06%  47.87% ########
# [ 4, 5)  331  10.86%  58.73% ###
# [ 5, 5] 1258  41.27% 100.00% ##########
#
# Number of training obs by leaf:
# Count: 3048 Average: 68.853 StdDev: 120.201
# Min: 5 Max: 596 Ignored: 0
# ----------------------------------------------
# [   5,  34) 2043  67.03%  67.03% ##########
# [  34,  64)  310  10.17%  77.20% ##
# [  64,  93)   87   2.85%  80.05%
# [  93, 123)   13   0.43%  80.48%
# [ 123, 153)   53   1.74%  82.22%
# [ 153, 182)   16   0.52%  82.74%
# [ 182, 212)   60   1.97%  84.71%
# [ 212, 241)  111   3.64%  88.35% #
# [ 241, 271)   77   2.53%  90.88%
# [ 271, 301)   53   1.74%  92.62%
# [ 301, 330)   33   1.08%  93.70%
# [ 330, 360)   34   1.12%  94.82%
# [ 360, 389)   18   0.59%  95.41%
# [ 389, 419)   78   2.56%  97.97%
# [ 419, 449)    5   0.16%  98.13%
# [ 449, 478)   12   0.39%  98.52%
# [ 478, 508)   40   1.31%  99.84%
# [ 508, 537)    0   0.00%  99.84%
# [ 537, 567)    0   0.00%  99.84%
# [ 567, 596]    5   0.16% 100.00%
#
# Attribute in nodes:
# 	318 : LargeAreaLowGrayLevelEmphasis [NUMERICAL]
# 	251 : SmallAreaEmphasis [NUMERICAL]
# 	251 : SizeZoneNonUniformityNormalized [NUMERICAL]
# 	249 : GrayLevelNonUniformity [NUMERICAL]
# 	246 : LowGrayLevelZoneEmphasis [NUMERICAL]
# 	240 : Skewness [NUMERICAL]
# 	198 : GrayLevelVariance [NUMERICAL]
# 	164 : HighGrayLevelZoneEmphasis [NUMERICAL]
# 	89 : LargeAreaHighGrayLevelEmphasis [NUMERICAL]
# 	86 : ZonePercentage [NUMERICAL]
# 	64 : SmallAreaHighGrayLevelEmphasis [NUMERICAL]
# 	64 : Entropy [NUMERICAL]
# 	60 : Range [NUMERICAL]
# 	58 : SizeZoneNonUniformity [NUMERICAL]
# 	46 : LargeAreaEmphasis [NUMERICAL]
# 	32 : SmallAreaLowGrayLevelEmphasis [NUMERICAL]
# 	32 : InterquartileRange [NUMERICAL]
# 	31 : TotalEnergy [NUMERICAL]
# 	30 : Variance [NUMERICAL]
# 	29 : RootMeanSquared [NUMERICAL]
# 	26 : GrayLevelNonUniformityNormalized [NUMERICAL]
# 	23 : Maximum [NUMERICAL]
# 	22 : ZoneEntropy [NUMERICAL]
# 	22 : Kurtosis [NUMERICAL]
# 	19 : ZoneVariance [NUMERICAL]
# 	19 : RobustMeanAbsoluteDeviation [NUMERICAL]
# 	18 : Energy [NUMERICAL]
# 	16 : Uniformity [NUMERICAL]
# 	12 : Median [NUMERICAL]
# 	9 : Mean [NUMERICAL]
# 	9 : 10Percentile [NUMERICAL]
# 	8 : Minimum [NUMERICAL]
# 	7 : 90Percentile [NUMERICAL]
# 	4 : MeanAbsoluteDeviation [NUMERICAL]
#
# Attribute in nodes with depth <= 0:
# 	102 : LargeAreaLowGrayLevelEmphasis [NUMERICAL]
# 	92 : SizeZoneNonUniformityNormalized [NUMERICAL]
# 	83 : SmallAreaEmphasis [NUMERICAL]
# 	7 : LargeAreaHighGrayLevelEmphasis [NUMERICAL]
# 	6 : Variance [NUMERICAL]
# 	3 : InterquartileRange [NUMERICAL]
# 	2 : Energy [NUMERICAL]
# 	1 : TotalEnergy [NUMERICAL]
#
# Attribute in nodes with depth <= 1:
# 	211 : LargeAreaLowGrayLevelEmphasis [NUMERICAL]
# 	204 : SizeZoneNonUniformityNormalized [NUMERICAL]
# 	177 : SmallAreaEmphasis [NUMERICAL]
# 	170 : GrayLevelNonUniformity [NUMERICAL]
# 	31 : LargeAreaHighGrayLevelEmphasis [NUMERICAL]
# 	13 : LowGrayLevelZoneEmphasis [NUMERICAL]
# 	12 : Variance [NUMERICAL]
# 	12 : Skewness [NUMERICAL]
# 	6 : ZoneVariance [NUMERICAL]
# 	6 : ZonePercentage [NUMERICAL]
# 	6 : SmallAreaHighGrayLevelEmphasis [NUMERICAL]
# 	5 : InterquartileRange [NUMERICAL]
# 	5 : GrayLevelVariance [NUMERICAL]
# 	5 : GrayLevelNonUniformityNormalized [NUMERICAL]
# 	4 : LargeAreaEmphasis [NUMERICAL]
# 	3 : ZoneEntropy [NUMERICAL]
# 	3 : SmallAreaLowGrayLevelEmphasis [NUMERICAL]
# 	3 : HighGrayLevelZoneEmphasis [NUMERICAL]
# 	3 : Energy [NUMERICAL]
# 	2 : SizeZoneNonUniformity [NUMERICAL]
# 	2 : Mean [NUMERICAL]
# 	1 : TotalEnergy [NUMERICAL]
#
# Attribute in nodes with depth <= 2:
# 	259 : LargeAreaLowGrayLevelEmphasis [NUMERICAL]
# 	239 : SizeZoneNonUniformityNormalized [NUMERICAL]
# 	222 : SmallAreaEmphasis [NUMERICAL]
# 	208 : Skewness [NUMERICAL]
# 	200 : GrayLevelNonUniformity [NUMERICAL]
# 	99 : HighGrayLevelZoneEmphasis [NUMERICAL]
# 	45 : SizeZoneNonUniformity [NUMERICAL]
# 	44 : LargeAreaHighGrayLevelEmphasis [NUMERICAL]
# 	38 : ZonePercentage [NUMERICAL]
# 	37 : LowGrayLevelZoneEmphasis [NUMERICAL]
# 	33 : GrayLevelVariance [NUMERICAL]
# 	21 : SmallAreaHighGrayLevelEmphasis [NUMERICAL]
# 	19 : Range [NUMERICAL]
# 	18 : SmallAreaLowGrayLevelEmphasis [NUMERICAL]
# 	16 : LargeAreaEmphasis [NUMERICAL]
# 	16 : GrayLevelNonUniformityNormalized [NUMERICAL]
# 	14 : Variance [NUMERICAL]
# 	13 : ZoneVariance [NUMERICAL]
# 	12 : InterquartileRange [NUMERICAL]
# 	10 : ZoneEntropy [NUMERICAL]
# 	10 : RootMeanSquared [NUMERICAL]
# 	9 : TotalEnergy [NUMERICAL]
# 	8 : RobustMeanAbsoluteDeviation [NUMERICAL]
# 	8 : Median [NUMERICAL]
# 	7 : Uniformity [NUMERICAL]
# 	7 : Mean [NUMERICAL]
# 	6 : Entropy [NUMERICAL]
# 	5 : Energy [NUMERICAL]
# 	5 : 90Percentile [NUMERICAL]
# 	4 : Kurtosis [NUMERICAL]
# 	3 : Minimum [NUMERICAL]
# 	3 : MeanAbsoluteDeviation [NUMERICAL]
# 	3 : Maximum [NUMERICAL]
# 	2 : 10Percentile [NUMERICAL]
#
# Attribute in nodes with depth <= 3:
# 	270 : LargeAreaLowGrayLevelEmphasis [NUMERICAL]
# 	246 : SmallAreaEmphasis [NUMERICAL]
# 	242 : SizeZoneNonUniformityNormalized [NUMERICAL]
# 	227 : Skewness [NUMERICAL]
# 	223 : GrayLevelNonUniformity [NUMERICAL]
# 	218 : LowGrayLevelZoneEmphasis [NUMERICAL]
# 	135 : HighGrayLevelZoneEmphasis [NUMERICAL]
# 	56 : ZonePercentage [NUMERICAL]
# 	53 : LargeAreaHighGrayLevelEmphasis [NUMERICAL]
# 	48 : SizeZoneNonUniformity [NUMERICAL]
# 	39 : SmallAreaHighGrayLevelEmphasis [NUMERICAL]
# 	37 : GrayLevelVariance [NUMERICAL]
# 	35 : Range [NUMERICAL]
# 	34 : Entropy [NUMERICAL]
# 	28 : LargeAreaEmphasis [NUMERICAL]
# 	24 : SmallAreaLowGrayLevelEmphasis [NUMERICAL]
# 	21 : RootMeanSquared [NUMERICAL]
# 	20 : Variance [NUMERICAL]
# 	19 : TotalEnergy [NUMERICAL]
# 	16 : ZoneVariance [NUMERICAL]
# 	16 : InterquartileRange [NUMERICAL]
# 	16 : GrayLevelNonUniformityNormalized [NUMERICAL]
# 	13 : RobustMeanAbsoluteDeviation [NUMERICAL]
# 	12 : ZoneEntropy [NUMERICAL]
# 	11 : Median [NUMERICAL]
# 	11 : Energy [NUMERICAL]
# 	9 : Uniformity [NUMERICAL]
# 	9 : Mean [NUMERICAL]
# 	9 : Maximum [NUMERICAL]
# 	8 : Minimum [NUMERICAL]
# 	5 : Kurtosis [NUMERICAL]
# 	5 : 90Percentile [NUMERICAL]
# 	5 : 10Percentile [NUMERICAL]
# 	3 : MeanAbsoluteDeviation [NUMERICAL]
#
# Attribute in nodes with depth <= 5:
# 	318 : LargeAreaLowGrayLevelEmphasis [NUMERICAL]
# 	251 : SmallAreaEmphasis [NUMERICAL]
# 	251 : SizeZoneNonUniformityNormalized [NUMERICAL]
# 	249 : GrayLevelNonUniformity [NUMERICAL]
# 	246 : LowGrayLevelZoneEmphasis [NUMERICAL]
# 	240 : Skewness [NUMERICAL]
# 	198 : GrayLevelVariance [NUMERICAL]
# 	164 : HighGrayLevelZoneEmphasis [NUMERICAL]
# 	89 : LargeAreaHighGrayLevelEmphasis [NUMERICAL]
# 	86 : ZonePercentage [NUMERICAL]
# 	64 : SmallAreaHighGrayLevelEmphasis [NUMERICAL]
# 	64 : Entropy [NUMERICAL]
# 	60 : Range [NUMERICAL]
# 	58 : SizeZoneNonUniformity [NUMERICAL]
# 	46 : LargeAreaEmphasis [NUMERICAL]
# 	32 : SmallAreaLowGrayLevelEmphasis [NUMERICAL]
# 	32 : InterquartileRange [NUMERICAL]
# 	31 : TotalEnergy [NUMERICAL]
# 	30 : Variance [NUMERICAL]
# 	29 : RootMeanSquared [NUMERICAL]
# 	26 : GrayLevelNonUniformityNormalized [NUMERICAL]
# 	23 : Maximum [NUMERICAL]
# 	22 : ZoneEntropy [NUMERICAL]
# 	22 : Kurtosis [NUMERICAL]
# 	19 : ZoneVariance [NUMERICAL]
# 	19 : RobustMeanAbsoluteDeviation [NUMERICAL]
# 	18 : Energy [NUMERICAL]
# 	16 : Uniformity [NUMERICAL]
# 	12 : Median [NUMERICAL]
# 	9 : Mean [NUMERICAL]
# 	9 : 10Percentile [NUMERICAL]
# 	8 : Minimum [NUMERICAL]
# 	7 : 90Percentile [NUMERICAL]
# 	4 : MeanAbsoluteDeviation [NUMERICAL]
#
# Condition type in nodes:
# 	2752 : HigherCondition
# Condition type in nodes with depth <= 0:
# 	296 : HigherCondition
# Condition type in nodes with depth <= 1:
# 	884 : HigherCondition
# Condition type in nodes with depth <= 2:
# 	1643 : HigherCondition
# Condition type in nodes with depth <= 3:
# 	2123 : HigherCondition
# Condition type in nodes with depth <= 5:
# 	2752 : HigherCondition
#
# Training logs:
# Number of iteration to final model: 296
# 	Iter:1 train-loss:1.196276 valid-loss:1.196304  train-accuracy:1.000000 valid-accuracy:1.000000
# 	Iter:2 train-loss:1.040657 valid-loss:1.040680  train-accuracy:1.000000 valid-accuracy:1.000000
# 	Iter:3 train-loss:0.910888 valid-loss:0.910907  train-accuracy:1.000000 valid-accuracy:1.000000
# 	Iter:4 train-loss:0.801196 valid-loss:0.801212  train-accuracy:1.000000 valid-accuracy:1.000000
# 	Iter:5 train-loss:0.707493 valid-loss:0.707507  train-accuracy:1.000000 valid-accuracy:1.000000
# 	Iter:6 train-loss:0.626775 valid-loss:0.626787  train-accuracy:1.000000 valid-accuracy:1.000000
# 	Iter:16 train-loss:0.206083 valid-loss:0.206087  train-accuracy:1.000000 valid-accuracy:1.000000
# 	Iter:26 train-loss:0.073115 valid-loss:0.073116  train-accuracy:1.000000 valid-accuracy:1.000000
# 	Iter:36 train-loss:0.026556 valid-loss:0.026557  train-accuracy:1.000000 valid-accuracy:1.000000
# 	Iter:46 train-loss:0.009725 valid-loss:0.009725  train-accuracy:1.000000 valid-accuracy:1.000000
# 	Iter:56 train-loss:0.003571 valid-loss:0.003571  train-accuracy:1.000000 valid-accuracy:1.000000
# 	Iter:66 train-loss:0.001313 valid-loss:0.001313  train-accuracy:1.000000 valid-accuracy:1.000000
# 	Iter:76 train-loss:0.000482 valid-loss:0.000482  train-accuracy:1.000000 valid-accuracy:1.000000
# 	Iter:86 train-loss:0.000178 valid-loss:0.000178  train-accuracy:1.000000 valid-accuracy:1.000000
# 	Iter:96 train-loss:0.000071 valid-loss:0.000070  train-accuracy:1.000000 valid-accuracy:1.000000
# 	Iter:106 train-loss:0.000033 valid-loss:0.000030  train-accuracy:1.000000 valid-accuracy:1.000000
# 	Iter:116 train-loss:0.000017 valid-loss:0.000014  train-accuracy:1.000000 valid-accuracy:1.000000
# 	Iter:126 train-loss:0.000010 valid-loss:0.000008  train-accuracy:1.000000 valid-accuracy:1.000000
# 	Iter:136 train-loss:0.000007 valid-loss:0.000005  train-accuracy:1.000000 valid-accuracy:1.000000
# 	Iter:146 train-loss:0.000006 valid-loss:0.000004  train-accuracy:1.000000 valid-accuracy:1.000000
# 	Iter:156 train-loss:0.000005 valid-loss:0.000004  train-accuracy:1.000000 valid-accuracy:1.000000
# 	Iter:166 train-loss:0.000004 valid-loss:0.000003  train-accuracy:1.000000 valid-accuracy:1.000000
# 	Iter:176 train-loss:0.000004 valid-loss:0.000003  train-accuracy:1.000000 valid-accuracy:1.000000
# 	Iter:186 train-loss:0.000003 valid-loss:0.000002  train-accuracy:1.000000 valid-accuracy:1.000000
# 	Iter:196 train-loss:0.000003 valid-loss:0.000002  train-accuracy:1.000000 valid-accuracy:1.000000
# 	Iter:206 train-loss:0.000003 valid-loss:0.000002  train-accuracy:1.000000 valid-accuracy:1.000000
# 	Iter:216 train-loss:0.000002 valid-loss:0.000002  train-accuracy:1.000000 valid-accuracy:1.000000
# 	Iter:226 train-loss:0.000002 valid-loss:0.000002  train-accuracy:1.000000 valid-accuracy:1.000000
# 	Iter:236 train-loss:0.000002 valid-loss:0.000001  train-accuracy:1.000000 valid-accuracy:1.000000
# 	Iter:246 train-loss:0.000002 valid-loss:0.000001  train-accuracy:1.000000 valid-accuracy:1.000000
# 	Iter:256 train-loss:0.000002 valid-loss:0.000001  train-accuracy:1.000000 valid-accuracy:1.000000
# 	Iter:266 train-loss:0.000002 valid-loss:0.000001  train-accuracy:1.000000 valid-accuracy:1.000000
# 	Iter:276 train-loss:0.000002 valid-loss:0.000001  train-accuracy:1.000000 valid-accuracy:1.000000
# 	Iter:286 train-loss:0.000002 valid-loss:0.000001  train-accuracy:1.000000 valid-accuracy:1.000000
# 	Iter:296 train-loss:0.000001 valid-loss:0.000001  train-accuracy:1.000000 valid-accuracy:1.000000

# %%
# Model features
model.make_inspector().features()
# Out:
# ["10Percentile" (1; #0),
#  "90Percentile" (1; #1),
#  "Energy" (1; #2),
#  "Entropy" (1; #3),
#  "GrayLevelNonUniformity" (1; #4),
#  "GrayLevelNonUniformityNormalized" (1; #5),
#  "GrayLevelVariance" (1; #6),
#  "HighGrayLevelZoneEmphasis" (1; #7),
#  "InterquartileRange" (1; #8),
#  "Kurtosis" (1; #9),
#  "LargeAreaEmphasis" (1; #10),
#  "LargeAreaHighGrayLevelEmphasis" (1; #11),
#  "LargeAreaLowGrayLevelEmphasis" (1; #12),
#  "LowGrayLevelZoneEmphasis" (1; #13),
#  "Maximum" (1; #14),
#  "Mean" (1; #15),
#  "MeanAbsoluteDeviation" (1; #16),
#  "Median" (1; #17),
#  "Minimum" (1; #18),
#  "Range" (1; #19),
#  "RobustMeanAbsoluteDeviation" (1; #20),
#  "RootMeanSquared" (1; #21),
#  "SizeZoneNonUniformity" (1; #22),
#  "SizeZoneNonUniformityNormalized" (1; #23),
#  "Skewness" (1; #24),
#  "SmallAreaEmphasis" (1; #25),
#  "SmallAreaHighGrayLevelEmphasis" (1; #26),
#  "SmallAreaLowGrayLevelEmphasis" (1; #27),
#  "TotalEnergy" (1; #28),
#  "Uniformity" (1; #29),
#  "Variance" (1; #30),
#  "ZoneEntropy" (1; #31),
#  "ZonePercentage" (1; #32),
#  "ZoneVariance" (1; #33)]

# %%
# Feature importance
model.make_inspector().variable_importances()
# Out:
# {'INV_MEAN_MIN_DEPTH': [("GrayLevelNonUniformity" (1; #4),
#    0.31271234847621937),
#   ("SizeZoneNonUniformityNormalized" (1; #23), 0.3002726991514407),
#   ("SmallAreaEmphasis" (1; #25), 0.2939655396651083),
#   ("LargeAreaLowGrayLevelEmphasis" (1; #12), 0.2900962979832438),
#   ("Skewness" (1; #24), 0.26951317204681285),
#   ("LowGrayLevelZoneEmphasis" (1; #13), 0.24770438491834887),
#   ("LargeAreaHighGrayLevelEmphasis" (1; #11), 0.22879969930829827),
#   ("GrayLevelVariance" (1; #6), 0.22356789765904816),
#   ("HighGrayLevelZoneEmphasis" (1; #7), 0.22203911676403723),
#   ("Variance" (1; #30), 0.22157856508963703),
#   ("Range" (1; #19), 0.22060378743255898),
#   ("InterquartileRange" (1; #8), 0.22050345193725035),
#   ("SizeZoneNonUniformity" (1; #22), 0.21970361817681772),
#   ("ZonePercentage" (1; #32), 0.2196418842618187),
#   ("SmallAreaHighGrayLevelEmphasis" (1; #26), 0.21946478694592483),
#   ("Entropy" (1; #3), 0.21899619390038336),
#   ("TotalEnergy" (1; #28), 0.21871149514956137),
#   ("Energy" (1; #2), 0.21850296507445396),
#   ("LargeAreaEmphasis" (1; #10), 0.21839239803082247),
#   ("RootMeanSquared" (1; #21), 0.2179844172892408),
#   ("SmallAreaLowGrayLevelEmphasis" (1; #27), 0.21789903532455035),
#   ("GrayLevelNonUniformityNormalized" (1; #5), 0.21787368765872384),
#   ("Mean" (1; #15), 0.21767545124392354),
#   ("ZoneVariance" (1; #33), 0.21738575225213488),
#   ("RobustMeanAbsoluteDeviation" (1; #20), 0.21736449274980152),
#   ("Kurtosis" (1; #9), 0.21726217520315824),
#   ("ZoneEntropy" (1; #31), 0.21718539025108474),
#   ("Maximum" (1; #14), 0.21717332119053748),
#   ("Median" (1; #17), 0.2171544702155203),
#   ("Uniformity" (1; #29), 0.21713017387287062),
#   ("Minimum" (1; #18), 0.21695841835846535),
#   ("90Percentile" (1; #1), 0.21685679305916558),
#   ("10Percentile" (1; #0), 0.21682678757303037),
#   ("MeanAbsoluteDeviation" (1; #16), 0.2167536367366098)],
#  'NUM_AS_ROOT': [("LargeAreaLowGrayLevelEmphasis" (1; #12), 102.0),
#   ("SizeZoneNonUniformityNormalized" (1; #23), 92.0),
#   ("SmallAreaEmphasis" (1; #25), 83.0),
#   ("LargeAreaHighGrayLevelEmphasis" (1; #11), 7.0),
#   ("Variance" (1; #30), 6.0),
#   ("InterquartileRange" (1; #8), 3.0),
#   ("Energy" (1; #2), 2.0),
#   ("TotalEnergy" (1; #28), 1.0)],
#  'SUM_SCORE': [("LargeAreaLowGrayLevelEmphasis" (1; #12), 952.8487216653858),
#   ("LargeAreaHighGrayLevelEmphasis" (1; #11), 3.5954957577092286e-06),
#   ("Variance" (1; #30), 9.015930374635622e-07),
#   ("SizeZoneNonUniformityNormalized" (1; #23), 6.112867639863326e-07),
#   ("GrayLevelNonUniformity" (1; #4), 5.627504772336955e-07),
#   ("SmallAreaEmphasis" (1; #25), 5.316286359847547e-07),
#   ("Skewness" (1; #24), 3.4047235245256927e-07),
#   ("LowGrayLevelZoneEmphasis" (1; #13), 2.2941801301459786e-07),
#   ("InterquartileRange" (1; #8), 1.854331049720688e-07),
#   ("Range" (1; #19), 1.1911231804306177e-07),
#   ("Energy" (1; #2), 9.601451490233501e-08),
#   ("Mean" (1; #15), 4.813480477586183e-08),
#   ("LargeAreaEmphasis" (1; #10), 4.379402085502327e-08),
#   ("TotalEnergy" (1; #28), 3.9859586801624664e-08),
#   ("SmallAreaHighGrayLevelEmphasis" (1; #26), 3.4147168978161286e-08),
#   ("HighGrayLevelZoneEmphasis" (1; #7), 2.569964916677086e-08),
#   ("SizeZoneNonUniformity" (1; #22), 2.3751479567707815e-08),
#   ("Entropy" (1; #3), 2.266450294776798e-08),
#   ("RootMeanSquared" (1; #21), 2.2219576858282104e-08),
#   ("GrayLevelVariance" (1; #6), 9.236061945395319e-09),
#   ("ZonePercentage" (1; #32), 7.141994540749502e-09),
#   ("Kurtosis" (1; #9), 5.4035862016050625e-09),
#   ("SmallAreaLowGrayLevelEmphasis" (1; #27), 3.350888840875273e-09),
#   ("Maximum" (1; #14), 3.0820088317317425e-09),
#   ("ZoneVariance" (1; #33), 2.3783147223218486e-09),
#   ("Uniformity" (1; #29), 2.172444391800301e-09),
#   ("ZoneEntropy" (1; #31), 1.5279699181643767e-09),
#   ("GrayLevelNonUniformityNormalized" (1; #5), 9.012518324510528e-10),
#   ("Median" (1; #17), 8.345310986242064e-10),
#   ("RobustMeanAbsoluteDeviation" (1; #20), 6.425688202669148e-10),
#   ("Minimum" (1; #18), 6.063815312918723e-10),
#   ("MeanAbsoluteDeviation" (1; #16), 1.696632821145285e-10),
#   ("90Percentile" (1; #1), 3.4826603551943656e-13),
#   ("10Percentile" (1; #0), 4.696289478942086e-17)],
#  'NUM_NODES': [("LargeAreaLowGrayLevelEmphasis" (1; #12), 318.0),
#   ("SizeZoneNonUniformityNormalized" (1; #23), 251.0),
#   ("SmallAreaEmphasis" (1; #25), 251.0),
#   ("GrayLevelNonUniformity" (1; #4), 249.0),
#   ("LowGrayLevelZoneEmphasis" (1; #13), 246.0),
#   ("Skewness" (1; #24), 240.0),
#   ("GrayLevelVariance" (1; #6), 198.0),
#   ("HighGrayLevelZoneEmphasis" (1; #7), 164.0),
#   ("LargeAreaHighGrayLevelEmphasis" (1; #11), 89.0),
#   ("ZonePercentage" (1; #32), 86.0),
#   ("Entropy" (1; #3), 64.0),
#   ("SmallAreaHighGrayLevelEmphasis" (1; #26), 64.0),
#   ("Range" (1; #19), 60.0),
#   ("SizeZoneNonUniformity" (1; #22), 58.0),
#   ("LargeAreaEmphasis" (1; #10), 46.0),
#   ("InterquartileRange" (1; #8), 32.0),
#   ("SmallAreaLowGrayLevelEmphasis" (1; #27), 32.0),
#   ("TotalEnergy" (1; #28), 31.0),
#   ("Variance" (1; #30), 30.0),
#   ("RootMeanSquared" (1; #21), 29.0),
#   ("GrayLevelNonUniformityNormalized" (1; #5), 26.0),
#   ("Maximum" (1; #14), 23.0),
#   ("Kurtosis" (1; #9), 22.0),
#   ("ZoneEntropy" (1; #31), 22.0),
#   ("RobustMeanAbsoluteDeviation" (1; #20), 19.0),
#   ("ZoneVariance" (1; #33), 19.0),
#   ("Energy" (1; #2), 18.0),
#   ("Uniformity" (1; #29), 16.0),
#   ("Median" (1; #17), 12.0),
#   ("10Percentile" (1; #0), 9.0),
#   ("Mean" (1; #15), 9.0),
#   ("Minimum" (1; #18), 8.0),
#   ("90Percentile" (1; #1), 7.0),
#   ("MeanAbsoluteDeviation" (1; #16), 4.0)]}

# %%
# Model self evaluation
model.make_inspector().evaluation()
# Out:
# Evaluation(num_examples=None, accuracy=1.0, loss=9.843722637015162e-07, rmse=None, ndcg=None, aucs=None, auuc=None, qini=None)

# %%
logs = model.make_inspector().training_logs()

plt.figure(figsize=(12, 4))
plt.subplot(1, 2, 1)
plt.plot([log.num_trees for log in logs], [log.evaluation.accuracy for log in logs])
plt.xlabel("Number of trees")
plt.ylabel("Accuracy (out-of-bag)")
plt.subplot(1, 2, 2)
plt.plot([log.num_trees for log in logs], [log.evaluation.loss for log in logs])
plt.xlabel("Number of trees")
plt.ylabel("Logloss (out-of-bag)")
plt.show()

# %% [markdown]
# Calculate the score of our hold-out validation dataset

# %%
predictions = model.predict(val_ds)
y_true      = validation_data["label"]

from sklearn.metrics import roc_auc_score
ROC_AUC = roc_auc_score(y_true, predictions)
print("The ROC AUC score is %.5f" % ROC_AUC )
# Out:
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 70ms/step
# The ROC AUC score is 1.00000

# %%
# Compute binary classification metrics with sklearn
import numpy as np
from sklearn.metrics import (
    accuracy_score,
    precision_score,
    recall_score,
    f1_score,
    roc_auc_score,
    average_precision_score,
    confusion_matrix,
    classification_report,
    matthews_corrcoef,
    log_loss,
    brier_score_loss,
)

# Get predictions (probabilities or class labels)
preds = model.predict(test_ds)
# If model outputs probabilities, convert to labels by threshold 0.5
if preds.ndim == 2:
    # For TFDF classification, preds may be class probabilities with shape (N, 2)
    if preds.shape[1] == 2:
        pos_probs = preds[:, 1]
    else:
        # If single-probability column (positive class)
        pos_probs = preds[:, -1]
    y_pred = (pos_probs >= 0.5).astype(int)
else:
    # Already class labels
    y_pred = preds.astype(int)
    pos_probs = None

# Ground truth labels (must be 0/1 integers)
y_true = test_data["label"].astype(int).to_numpy()

# Core metrics
metrics = {}
metrics["accuracy"] = accuracy_score(y_true, y_pred)
metrics["precision"] = precision_score(y_true, y_pred, zero_division=0)
metrics["recall"] = recall_score(y_true, y_pred, zero_division=0)
metrics["f1"] = f1_score(y_true, y_pred, zero_division=0)
metrics["mcc"] = matthews_corrcoef(y_true, y_pred)

# Probabilistic metrics (only if we have probabilities)
if pos_probs is not None:
    metrics["roc_auc"] = roc_auc_score(y_true, pos_probs)
    metrics["pr_auc"] = average_precision_score(y_true, pos_probs)
    metrics["log_loss"] = log_loss(y_true, pos_probs, labels=[0,1])
    metrics["brier_score"] = brier_score_loss(y_true, pos_probs)

# Confusion matrix and detailed report
cm = confusion_matrix(y_true, y_pred, labels=[0,1])
report = classification_report(y_true, y_pred, digits=4)

print("Sklearn binary metrics:")
for k, v in metrics.items():
    print(f"{k}: {v:.4f}")
print("\nConfusion matrix:\n", cm)
print("\nClassification report:\n", report)
# Out:
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 75ms/step
# Sklearn binary metrics:
# accuracy: 1.0000
# precision: 1.0000
# recall: 1.0000
# f1: 1.0000
# mcc: 1.0000
# roc_auc: 1.0000
# pr_auc: 1.0000
# log_loss: 0.0000
# brier_score: 0.0000
#
# Confusion matrix:
#  [[108   0]
#  [  0 114]]
#
# Classification report:
#                precision    recall  f1-score   support
#
#            0     1.0000    1.0000    1.0000       108
#            1     1.0000    1.0000    1.0000       114
#
#     accuracy                         1.0000       222
#    macro avg     1.0000    1.0000    1.0000       222
# weighted avg     1.0000    1.0000    1.0000       222
