# %%
# Import packages and modules
import numpy  as np
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow_decision_forests as tfdf

from sklearn.model_selection import train_test_split
# Out:
# 2026-08-15 05:07:46.947253: I tensorflow/core/util/port.cc:113] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2026-08-15 05:07:47.303898: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2026-08-15 05:07:51.992951: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
# Check the version of TensorFlow Decision Forests
print("Found TensorFlow Decision Forests v" + tfdf.__version__)
# Out:
# Found TensorFlow Decision Forests v1.9.1

# %%
datasetPath = 'dataset/firstorder/kernel5/dataset.csv'

# %%
# Parameters
datasetPath = "dataset/glszm/kernel6/1.dataset.csv"

# %%
# train/validation/test = 70/10/20
dataset = pd.read_csv(datasetPath)

train_data, temp_data = train_test_split(dataset, test_size=0.3, random_state=42)
validation_data, test_data = train_test_split(temp_data, test_size=2/3, random_state=42)

# %%
from sklearn.utils.class_weight import compute_class_weight

# tinh class weight tren tap train
classes = np.array([0, 1])
weights = compute_class_weight(class_weight="balanced", classes=classes, y=train_data["label"])
class_weight = {0: weights[0], 1: weights[1]}

# gan sample_weight cho tung dong
train_data["sample_weight"] = train_data["label"].map(class_weight)
validation_data["sample_weight"] = validation_data["label"].map(class_weight)
test_data["sample_weight"] = test_data["label"].map(class_weight)

# Convert the dataset into a TensorFlow dataset.
train_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    train_data, label="label", weight="sample_weight"
)         
val_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    validation_data, label="label", weight="sample_weight"
)
test_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    test_data, label="label", weight="sample_weight"
)
# Out:
# 2026-08-15 05:08:05.747185: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:984] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2026-08-15 05:08:05.748679: W tensorflow/core/common_runtime/gpu/gpu_device.cc:2251] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...

# %%
import keras

# %%
# %%time

# Train a Gradient Boosted Trees model.
model = tfdf.keras.GradientBoostedTreesModel()

# Add evaluation metrics
model.compile(
    metrics=["accuracy"]
)
model.fit(x=train_ds)

# # Train a Gradient Boosted Trees model.
# model = tfdf.keras.GradientBoostedTreesModel(num_trees=1500)
# model.fit(train_ds)
# Out:
# Use /tmp/tmpnap55elm as temporary training directory
# Reading training dataset...
# [WARNING 26-08-15 05:08:05.8917 UTC gradient_boosted_trees.cc:1840] "goss_alpha" set but "sampling_method" not equal to "GOSS".
# [WARNING 26-08-15 05:08:05.8921 UTC gradient_boosted_trees.cc:1851] "goss_beta" set but "sampling_method" not equal to "GOSS".
# [WARNING 26-08-15 05:08:05.8921 UTC gradient_boosted_trees.cc:1865] "selective_gradient_boosting_ratio" set but "sampling_method" not equal to "SELGB".
# Training dataset read in 0:00:02.572413. Found 507 examples.
# Training model...
# Model trained in 0:00:00.455746
# Compiling model...
# [INFO 26-08-15 05:08:08.9460 UTC kernel.cc:1233] Loading model from path /tmp/tmpnap55elm/model/ with prefix af6a506033b14889
# [INFO 26-08-15 05:08:08.9495 UTC quick_scorer_extended.cc:911] The binary was compiled without AVX2 support, but your CPU supports it. Enable it for faster model inference.
# [INFO 26-08-15 05:08:08.9497 UTC abstract_model.cc:1362] Engine "GradientBoostedTreesQuickScorerExtended" built
# [INFO 26-08-15 05:08:08.9497 UTC kernel.cc:1061] Use fast generic engine
# Model compiled.
# CPU times: user 5.7 s, sys: 686 ms, total: 6.38 s
# Wall time: 6.19 s

# %%
# Evaluate the model
evaluate = model.evaluate(val_ds, return_dict=True)
print()

for name, value in evaluate.items():
    print(f"{name}: {value:.4f}")
# Out:
# WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 1/1 [==============================] - ETA: 0s - loss: 0.0000e+00 - accuracy: 1.0000
# 1/1 [==============================] - 3s 3s/step - loss: 0.0000e+00 - accuracy: 1.0000
# loss: 0.0000
# accuracy: 1.0000

# %%
# Model Summary
model.summary()
# Out:
# Model: "gradient_boosted_trees_model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
# =================================================================
# Total params: 1 (1.00 Byte)
# Trainable params: 0 (0.00 Byte)
# Non-trainable params: 1 (1.00 Byte)
# _________________________________________________________________
# Type: "GRADIENT_BOOSTED_TREES"
# Task: CLASSIFICATION
# Label: "__LABEL"
#
# Input Features (16):
# 	GrayLevelNonUniformity
# 	GrayLevelNonUniformityNormalized
# 	GrayLevelVariance
# 	HighGrayLevelZoneEmphasis
# 	LargeAreaEmphasis
# 	LargeAreaHighGrayLevelEmphasis
# 	LargeAreaLowGrayLevelEmphasis
# 	LowGrayLevelZoneEmphasis
# 	SizeZoneNonUniformity
# 	SizeZoneNonUniformityNormalized
# 	SmallAreaEmphasis
# 	SmallAreaHighGrayLevelEmphasis
# 	SmallAreaLowGrayLevelEmphasis
# 	ZoneEntropy
# 	ZonePercentage
# 	ZoneVariance
#
# Trained with weights
#
# Variable Importance: INV_MEAN_MIN_DEPTH:
#     1.   "SmallAreaHighGrayLevelEmphasis"  0.316849 ################
#     2.                      "ZoneEntropy"  0.303712 ##############
#     3.                "GrayLevelVariance"  0.259678 #######
#     4.    "LargeAreaLowGrayLevelEmphasis"  0.242935 #####
#     5. "GrayLevelNonUniformityNormalized"  0.239314 ####
#     6.        "HighGrayLevelZoneEmphasis"  0.235042 ####
#     7.    "SmallAreaLowGrayLevelEmphasis"  0.225172 ##
#     8.         "LowGrayLevelZoneEmphasis"  0.221760 ##
#     9.  "SizeZoneNonUniformityNormalized"  0.221572 ##
#    10.                     "ZoneVariance"  0.215476 #
#    11.           "GrayLevelNonUniformity"  0.213815
#    12.                   "ZonePercentage"  0.212713
#    13.            "SizeZoneNonUniformity"  0.211309
#    14.                "LargeAreaEmphasis"  0.210950
#    15.   "LargeAreaHighGrayLevelEmphasis"  0.210070
#    16.                "SmallAreaEmphasis"  0.207062
#
# Variable Importance: NUM_AS_ROOT:
#     1.   "SmallAreaHighGrayLevelEmphasis" 48.000000 ################
#     2.                      "ZoneEntropy" 38.000000 ############
#     3.                "GrayLevelVariance" 14.000000 ####
#     4.  "SizeZoneNonUniformityNormalized"  9.000000 ##
#     5. "GrayLevelNonUniformityNormalized"  7.000000 ##
#     6.        "HighGrayLevelZoneEmphasis"  6.000000 #
#     7.                "LargeAreaEmphasis"  1.000000
#
# Variable Importance: NUM_NODES:
#     1.                      "ZoneEntropy" 170.000000 ################
#     2.    "LargeAreaLowGrayLevelEmphasis" 134.000000 ############
#     3.         "LowGrayLevelZoneEmphasis" 122.000000 ##########
#     4.                "GrayLevelVariance" 121.000000 ##########
#     5.        "HighGrayLevelZoneEmphasis" 119.000000 ##########
#     6.   "SmallAreaHighGrayLevelEmphasis" 101.000000 ########
#     7. "GrayLevelNonUniformityNormalized" 84.000000 ######
#     8.    "SmallAreaLowGrayLevelEmphasis" 74.000000 #####
#     9.            "SizeZoneNonUniformity" 60.000000 ###
#    10.  "SizeZoneNonUniformityNormalized" 49.000000 ##
#    11.                   "ZonePercentage" 44.000000 ##
#    12.   "LargeAreaHighGrayLevelEmphasis" 36.000000 #
#    13.                "SmallAreaEmphasis" 33.000000
#    14.                     "ZoneVariance" 33.000000
#    15.           "GrayLevelNonUniformity" 27.000000
#    16.                "LargeAreaEmphasis" 24.000000
#
# Variable Importance: SUM_SCORE:
#     1.   "SmallAreaHighGrayLevelEmphasis" 559.492647 ################
#     2.                "GrayLevelVariance" 15.803674
#     3.    "LargeAreaLowGrayLevelEmphasis" 13.939699
#     4.                      "ZoneEntropy" 12.468886
#     5.                     "ZoneVariance"  6.774721
#     6. "GrayLevelNonUniformityNormalized"  4.459142
#     7.    "SmallAreaLowGrayLevelEmphasis"  1.069789
#     8.                "LargeAreaEmphasis"  1.061711
#     9.   "LargeAreaHighGrayLevelEmphasis"  0.832683
#    10.         "LowGrayLevelZoneEmphasis"  0.829689
#    11.           "GrayLevelNonUniformity"  0.814264
#    12.        "HighGrayLevelZoneEmphasis"  0.783644
#    13.            "SizeZoneNonUniformity"  0.780809
#    14.                   "ZonePercentage"  0.244008
#    15.                "SmallAreaEmphasis"  0.152231
#    16.  "SizeZoneNonUniformityNormalized"  0.100345
#
#
#
# Loss: BINOMIAL_LOG_LIKELIHOOD
# Validation loss value: 0.0127512
# Number of trees per iteration: 1
# Node format: NOT_SET
# Number of trees: 123
# Total number of nodes: 2585
#
# Number of nodes by tree:
# Count: 123 Average: 21.0163 StdDev: 3.40727
# Min: 13 Max: 29 Ignored: 0
# ----------------------------------------------
# [ 13, 14)  1   0.81%   0.81%
# [ 14, 15)  0   0.00%   0.81%
# [ 15, 16)  9   7.32%   8.13% ###
# [ 16, 17)  0   0.00%   8.13%
# [ 17, 18) 13  10.57%  18.70% ####
# [ 18, 19)  0   0.00%  18.70%
# [ 19, 20) 25  20.33%  39.02% #######
# [ 20, 21)  0   0.00%  39.02%
# [ 21, 22) 23  18.70%  57.72% #######
# [ 22, 23)  0   0.00%  57.72%
# [ 23, 24) 34  27.64%  85.37% ##########
# [ 24, 25)  0   0.00%  85.37%
# [ 25, 26) 11   8.94%  94.31% ###
# [ 26, 27)  0   0.00%  94.31%
# [ 27, 28)  1   0.81%  95.12%
# [ 28, 29)  0   0.00%  95.12%
# [ 29, 29]  6   4.88% 100.00% ##
#
# Depth by leafs:
# Count: 1354 Average: 3.9291 StdDev: 1.09693
# Min: 1 Max: 5 Ignored: 0
# ----------------------------------------------
# [ 1, 2)  21   1.55%   1.55%
# [ 2, 3) 161  11.89%  13.44% ###
# [ 3, 4) 257  18.98%  32.42% #####
# [ 4, 5) 369  27.25%  59.68% #######
# [ 5, 5] 546  40.32% 100.00% ##########
#
# Number of training obs by leaf:
# Count: 1354 Average: 41.6056 StdDev: 108.898
# Min: 5 Max: 414 Ignored: 0
# ----------------------------------------------
# [   5,  25) 1208  89.22%  89.22% ##########
# [  25,  46)   10   0.74%  89.96%
# [  46,  66)    6   0.44%  90.40%
# [  66,  87)    6   0.44%  90.84%
# [  87, 107)    0   0.00%  90.84%
# [ 107, 128)    1   0.07%  90.92%
# [ 128, 148)    0   0.00%  90.92%
# [ 148, 169)    0   0.00%  90.92%
# [ 169, 189)    0   0.00%  90.92%
# [ 189, 210)    0   0.00%  90.92%
# [ 210, 230)    0   0.00%  90.92%
# [ 230, 251)    0   0.00%  90.92%
# [ 251, 271)    0   0.00%  90.92%
# [ 271, 292)    2   0.15%  91.06%
# [ 292, 312)    7   0.52%  91.58%
# [ 312, 333)    2   0.15%  91.73%
# [ 333, 353)    1   0.07%  91.80%
# [ 353, 374)    3   0.22%  92.02%
# [ 374, 394)   52   3.84%  95.86%
# [ 394, 414]   56   4.14% 100.00%
#
# Attribute in nodes:
# 	170 : ZoneEntropy [NUMERICAL]
# 	134 : LargeAreaLowGrayLevelEmphasis [NUMERICAL]
# 	122 : LowGrayLevelZoneEmphasis [NUMERICAL]
# 	121 : GrayLevelVariance [NUMERICAL]
# 	119 : HighGrayLevelZoneEmphasis [NUMERICAL]
# 	101 : SmallAreaHighGrayLevelEmphasis [NUMERICAL]
# 	84 : GrayLevelNonUniformityNormalized [NUMERICAL]
# 	74 : SmallAreaLowGrayLevelEmphasis [NUMERICAL]
# 	60 : SizeZoneNonUniformity [NUMERICAL]
# 	49 : SizeZoneNonUniformityNormalized [NUMERICAL]
# 	44 : ZonePercentage [NUMERICAL]
# 	36 : LargeAreaHighGrayLevelEmphasis [NUMERICAL]
# 	33 : ZoneVariance [NUMERICAL]
# 	33 : SmallAreaEmphasis [NUMERICAL]
# 	27 : GrayLevelNonUniformity [NUMERICAL]
# 	24 : LargeAreaEmphasis [NUMERICAL]
#
# Attribute in nodes with depth <= 0:
# 	48 : SmallAreaHighGrayLevelEmphasis [NUMERICAL]
# 	38 : ZoneEntropy [NUMERICAL]
# 	14 : GrayLevelVariance [NUMERICAL]
# 	9 : SizeZoneNonUniformityNormalized [NUMERICAL]
# 	7 : GrayLevelNonUniformityNormalized [NUMERICAL]
# 	6 : HighGrayLevelZoneEmphasis [NUMERICAL]
# 	1 : LargeAreaEmphasis [NUMERICAL]
#
# Attribute in nodes with depth <= 1:
# 	82 : ZoneEntropy [NUMERICAL]
# 	61 : LargeAreaLowGrayLevelEmphasis [NUMERICAL]
# 	54 : SmallAreaHighGrayLevelEmphasis [NUMERICAL]
# 	42 : GrayLevelVariance [NUMERICAL]
# 	31 : GrayLevelNonUniformityNormalized [NUMERICAL]
# 	15 : ZoneVariance [NUMERICAL]
# 	15 : SmallAreaLowGrayLevelEmphasis [NUMERICAL]
# 	10 : SizeZoneNonUniformityNormalized [NUMERICAL]
# 	10 : GrayLevelNonUniformity [NUMERICAL]
# 	9 : HighGrayLevelZoneEmphasis [NUMERICAL]
# 	6 : LargeAreaEmphasis [NUMERICAL]
# 	5 : LowGrayLevelZoneEmphasis [NUMERICAL]
# 	4 : LargeAreaHighGrayLevelEmphasis [NUMERICAL]
# 	2 : SmallAreaEmphasis [NUMERICAL]
# 	1 : ZonePercentage [NUMERICAL]
# 	1 : SizeZoneNonUniformity [NUMERICAL]
#
# Attribute in nodes with depth <= 2:
# 	104 : ZoneEntropy [NUMERICAL]
# 	103 : LargeAreaLowGrayLevelEmphasis [NUMERICAL]
# 	74 : SmallAreaHighGrayLevelEmphasis [NUMERICAL]
# 	70 : GrayLevelVariance [NUMERICAL]
# 	50 : HighGrayLevelZoneEmphasis [NUMERICAL]
# 	46 : GrayLevelNonUniformityNormalized [NUMERICAL]
# 	38 : SmallAreaLowGrayLevelEmphasis [NUMERICAL]
# 	34 : LowGrayLevelZoneEmphasis [NUMERICAL]
# 	26 : ZoneVariance [NUMERICAL]
# 	18 : ZonePercentage [NUMERICAL]
# 	16 : LargeAreaEmphasis [NUMERICAL]
# 	15 : SizeZoneNonUniformityNormalized [NUMERICAL]
# 	14 : SizeZoneNonUniformity [NUMERICAL]
# 	11 : LargeAreaHighGrayLevelEmphasis [NUMERICAL]
# 	11 : GrayLevelNonUniformity [NUMERICAL]
# 	7 : SmallAreaEmphasis [NUMERICAL]
#
# Attribute in nodes with depth <= 3:
# 	138 : ZoneEntropy [NUMERICAL]
# 	125 : LargeAreaLowGrayLevelEmphasis [NUMERICAL]
# 	96 : GrayLevelVariance [NUMERICAL]
# 	94 : HighGrayLevelZoneEmphasis [NUMERICAL]
# 	89 : SmallAreaHighGrayLevelEmphasis [NUMERICAL]
# 	73 : LowGrayLevelZoneEmphasis [NUMERICAL]
# 	63 : GrayLevelNonUniformityNormalized [NUMERICAL]
# 	56 : SmallAreaLowGrayLevelEmphasis [NUMERICAL]
# 	37 : ZonePercentage [NUMERICAL]
# 	37 : SizeZoneNonUniformityNormalized [NUMERICAL]
# 	33 : ZoneVariance [NUMERICAL]
# 	31 : SizeZoneNonUniformity [NUMERICAL]
# 	25 : SmallAreaEmphasis [NUMERICAL]
# 	24 : GrayLevelNonUniformity [NUMERICAL]
# 	20 : LargeAreaHighGrayLevelEmphasis [NUMERICAL]
# 	17 : LargeAreaEmphasis [NUMERICAL]
#
# Attribute in nodes with depth <= 5:
# 	170 : ZoneEntropy [NUMERICAL]
# 	134 : LargeAreaLowGrayLevelEmphasis [NUMERICAL]
# 	122 : LowGrayLevelZoneEmphasis [NUMERICAL]
# 	121 : GrayLevelVariance [NUMERICAL]
# 	119 : HighGrayLevelZoneEmphasis [NUMERICAL]
# 	101 : SmallAreaHighGrayLevelEmphasis [NUMERICAL]
# 	84 : GrayLevelNonUniformityNormalized [NUMERICAL]
# 	74 : SmallAreaLowGrayLevelEmphasis [NUMERICAL]
# 	60 : SizeZoneNonUniformity [NUMERICAL]
# 	49 : SizeZoneNonUniformityNormalized [NUMERICAL]
# 	44 : ZonePercentage [NUMERICAL]
# 	36 : LargeAreaHighGrayLevelEmphasis [NUMERICAL]
# 	33 : ZoneVariance [NUMERICAL]
# 	33 : SmallAreaEmphasis [NUMERICAL]
# 	27 : GrayLevelNonUniformity [NUMERICAL]
# 	24 : LargeAreaEmphasis [NUMERICAL]
#
# Condition type in nodes:
# 	1231 : HigherCondition
# Condition type in nodes with depth <= 0:
# 	123 : HigherCondition
# Condition type in nodes with depth <= 1:
# 	348 : HigherCondition
# Condition type in nodes with depth <= 2:
# 	637 : HigherCondition
# Condition type in nodes with depth <= 3:
# 	958 : HigherCondition
# Condition type in nodes with depth <= 5:
# 	1231 : HigherCondition
#
# Training logs:
# Number of iteration to final model: 123
# 	Iter:1 train-loss:1.201698 valid-loss:1.221408  train-accuracy:0.990839 valid-accuracy:0.973920
# 	Iter:2 train-loss:1.050593 valid-loss:1.078950  train-accuracy:0.994275 valid-accuracy:0.973920
# 	Iter:3 train-loss:0.924813 valid-loss:0.956137  train-accuracy:0.991985 valid-accuracy:0.973920
# 	Iter:4 train-loss:0.818295 valid-loss:0.857143  train-accuracy:0.993130 valid-accuracy:0.973920
# 	Iter:5 train-loss:0.727423 valid-loss:0.770018  train-accuracy:0.994275 valid-accuracy:0.973920
# 	Iter:6 train-loss:0.649167 valid-loss:0.691510  train-accuracy:0.993130 valid-accuracy:0.973920
# 	Iter:16 train-loss:0.238068 valid-loss:0.294968  train-accuracy:0.994275 valid-accuracy:0.973920
# 	Iter:26 train-loss:0.104061 valid-loss:0.168988  train-accuracy:0.995420 valid-accuracy:0.986960
# 	Iter:36 train-loss:0.047338 valid-loss:0.117598  train-accuracy:0.996565 valid-accuracy:0.986960
# 	Iter:46 train-loss:0.022910 valid-loss:0.090463  train-accuracy:0.998855 valid-accuracy:0.986960
# 	Iter:56 train-loss:0.008899 valid-loss:0.057329  train-accuracy:1.000000 valid-accuracy:0.986960
# 	Iter:66 train-loss:0.003364 valid-loss:0.027840  train-accuracy:1.000000 valid-accuracy:1.000000
# 	Iter:76 train-loss:0.001575 valid-loss:0.022516  train-accuracy:1.000000 valid-accuracy:1.000000
# 	Iter:86 train-loss:0.000713 valid-loss:0.016880  train-accuracy:1.000000 valid-accuracy:1.000000
# 	Iter:96 train-loss:0.000333 valid-loss:0.014960  train-accuracy:1.000000 valid-accuracy:1.000000
# 	Iter:106 train-loss:0.000166 valid-loss:0.018245  train-accuracy:1.000000 valid-accuracy:1.000000
# 	Iter:116 train-loss:0.000087 valid-loss:0.016104  train-accuracy:1.000000 valid-accuracy:1.000000
# 	Iter:126 train-loss:0.000048 valid-loss:0.013707  train-accuracy:1.000000 valid-accuracy:1.000000
# 	Iter:136 train-loss:0.000028 valid-loss:0.015858  train-accuracy:1.000000 valid-accuracy:1.000000
# 	Iter:146 train-loss:0.000019 valid-loss:0.016845  train-accuracy:1.000000 valid-accuracy:1.000000

# %%
# Model features
model.make_inspector().features()
# Out:
# ["GrayLevelNonUniformity" (1; #0),
#  "GrayLevelNonUniformityNormalized" (1; #1),
#  "GrayLevelVariance" (1; #2),
#  "HighGrayLevelZoneEmphasis" (1; #3),
#  "LargeAreaEmphasis" (1; #4),
#  "LargeAreaHighGrayLevelEmphasis" (1; #5),
#  "LargeAreaLowGrayLevelEmphasis" (1; #6),
#  "LowGrayLevelZoneEmphasis" (1; #7),
#  "SizeZoneNonUniformity" (1; #8),
#  "SizeZoneNonUniformityNormalized" (1; #9),
#  "SmallAreaEmphasis" (1; #10),
#  "SmallAreaHighGrayLevelEmphasis" (1; #11),
#  "SmallAreaLowGrayLevelEmphasis" (1; #12),
#  "ZoneEntropy" (1; #13),
#  "ZonePercentage" (1; #14),
#  "ZoneVariance" (1; #15)]

# %%
# Feature importance
model.make_inspector().variable_importances()
# Out:
# {'INV_MEAN_MIN_DEPTH': [("SmallAreaHighGrayLevelEmphasis" (1; #11),
#    0.31684880485012656),
#   ("ZoneEntropy" (1; #13), 0.30371212964273675),
#   ("GrayLevelVariance" (1; #2), 0.2596782088011339),
#   ("LargeAreaLowGrayLevelEmphasis" (1; #6), 0.24293465888747937),
#   ("GrayLevelNonUniformityNormalized" (1; #1), 0.23931395228674474),
#   ("HighGrayLevelZoneEmphasis" (1; #3), 0.23504174292500923),
#   ("SmallAreaLowGrayLevelEmphasis" (1; #12), 0.22517156980707906),
#   ("LowGrayLevelZoneEmphasis" (1; #7), 0.2217597215174979),
#   ("SizeZoneNonUniformityNormalized" (1; #9), 0.22157150652815993),
#   ("ZoneVariance" (1; #15), 0.21547612226673024),
#   ("GrayLevelNonUniformity" (1; #0), 0.21381533771027786),
#   ("ZonePercentage" (1; #14), 0.2127134203530357),
#   ("SizeZoneNonUniformity" (1; #8), 0.21130916010078432),
#   ("LargeAreaEmphasis" (1; #4), 0.21094978173327109),
#   ("LargeAreaHighGrayLevelEmphasis" (1; #5), 0.21006962808721058),
#   ("SmallAreaEmphasis" (1; #10), 0.2070618075871482)],
#  'NUM_AS_ROOT': [("SmallAreaHighGrayLevelEmphasis" (1; #11), 48.0),
#   ("ZoneEntropy" (1; #13), 38.0),
#   ("GrayLevelVariance" (1; #2), 14.0),
#   ("SizeZoneNonUniformityNormalized" (1; #9), 9.0),
#   ("GrayLevelNonUniformityNormalized" (1; #1), 7.0),
#   ("HighGrayLevelZoneEmphasis" (1; #3), 6.0),
#   ("LargeAreaEmphasis" (1; #4), 1.0)],
#  'SUM_SCORE': [("SmallAreaHighGrayLevelEmphasis" (1; #11), 559.4926465832557),
#   ("GrayLevelVariance" (1; #2), 15.803674044826696),
#   ("LargeAreaLowGrayLevelEmphasis" (1; #6), 13.93969901842851),
#   ("ZoneEntropy" (1; #13), 12.468885668412895),
#   ("ZoneVariance" (1; #15), 6.774720885533587),
#   ("GrayLevelNonUniformityNormalized" (1; #1), 4.459141598854013),
#   ("SmallAreaLowGrayLevelEmphasis" (1; #12), 1.0697891847804541),
#   ("LargeAreaEmphasis" (1; #4), 1.0617105382483665),
#   ("LargeAreaHighGrayLevelEmphasis" (1; #5), 0.8326827690231087),
#   ("LowGrayLevelZoneEmphasis" (1; #7), 0.8296887823882431),
#   ("GrayLevelNonUniformity" (1; #0), 0.8142636010306351),
#   ("HighGrayLevelZoneEmphasis" (1; #3), 0.7836438232320174),
#   ("SizeZoneNonUniformity" (1; #8), 0.7808086519283157),
#   ("ZonePercentage" (1; #14), 0.24400823595175697),
#   ("SmallAreaEmphasis" (1; #10), 0.1522310057952245),
#   ("SizeZoneNonUniformityNormalized" (1; #9), 0.1003449321901219)],
#  'NUM_NODES': [("ZoneEntropy" (1; #13), 170.0),
#   ("LargeAreaLowGrayLevelEmphasis" (1; #6), 134.0),
#   ("LowGrayLevelZoneEmphasis" (1; #7), 122.0),
#   ("GrayLevelVariance" (1; #2), 121.0),
#   ("HighGrayLevelZoneEmphasis" (1; #3), 119.0),
#   ("SmallAreaHighGrayLevelEmphasis" (1; #11), 101.0),
#   ("GrayLevelNonUniformityNormalized" (1; #1), 84.0),
#   ("SmallAreaLowGrayLevelEmphasis" (1; #12), 74.0),
#   ("SizeZoneNonUniformity" (1; #8), 60.0),
#   ("SizeZoneNonUniformityNormalized" (1; #9), 49.0),
#   ("ZonePercentage" (1; #14), 44.0),
#   ("LargeAreaHighGrayLevelEmphasis" (1; #5), 36.0),
#   ("SmallAreaEmphasis" (1; #10), 33.0),
#   ("ZoneVariance" (1; #15), 33.0),
#   ("GrayLevelNonUniformity" (1; #0), 27.0),
#   ("LargeAreaEmphasis" (1; #4), 24.0)]}

# %%
# Model self evaluation
model.make_inspector().evaluation()
# Out:
# Evaluation(num_examples=None, accuracy=1.0, loss=0.012751244939863682, rmse=None, ndcg=None, aucs=None, auuc=None, qini=None)

# %%
logs = model.make_inspector().training_logs()

plt.figure(figsize=(12, 4))
plt.subplot(1, 2, 1)
plt.plot([log.num_trees for log in logs], [log.evaluation.accuracy for log in logs])
plt.xlabel("Number of trees")
plt.ylabel("Accuracy (out-of-bag)")
plt.subplot(1, 2, 2)
plt.plot([log.num_trees for log in logs], [log.evaluation.loss for log in logs])
plt.xlabel("Number of trees")
plt.ylabel("Logloss (out-of-bag)")
plt.show()

# %% [markdown]
# Calculate the score of our hold-out validation dataset

# %%
predictions = model.predict(val_ds)
y_true      = validation_data["label"]

from sklearn.metrics import roc_auc_score
ROC_AUC = roc_auc_score(y_true, predictions)
print("The ROC AUC score is %.5f" % ROC_AUC )
# Out:
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 60ms/step
# The ROC AUC score is 1.00000

# %%
# Compute binary classification metrics with sklearn
import numpy as np
from sklearn.metrics import (
    accuracy_score,
    precision_score,
    recall_score,
    f1_score,
    roc_auc_score,
    average_precision_score,
    confusion_matrix,
    classification_report,
    matthews_corrcoef,
    log_loss,
    brier_score_loss,
)

# Get predictions (probabilities or class labels)
preds = model.predict(test_ds)
# If model outputs probabilities, convert to labels by threshold 0.5
if preds.ndim == 2:
    # For TFDF classification, preds may be class probabilities with shape (N, 2)
    if preds.shape[1] == 2:
        pos_probs = preds[:, 1]
    else:
        # If single-probability column (positive class)
        pos_probs = preds[:, -1]
    y_pred = (pos_probs >= 0.5).astype(int)
else:
    # Already class labels
    y_pred = preds.astype(int)
    pos_probs = None

# Ground truth labels (must be 0/1 integers)
y_true = test_data["label"].astype(int).to_numpy()

# Core metrics
metrics = {}
metrics["accuracy"] = accuracy_score(y_true, y_pred)
metrics["precision"] = precision_score(y_true, y_pred, zero_division=0)
metrics["recall"] = recall_score(y_true, y_pred, zero_division=0)
metrics["f1"] = f1_score(y_true, y_pred, zero_division=0)
metrics["mcc"] = matthews_corrcoef(y_true, y_pred)

# Probabilistic metrics (only if we have probabilities)
if pos_probs is not None:
    metrics["roc_auc"] = roc_auc_score(y_true, pos_probs)
    metrics["pr_auc"] = average_precision_score(y_true, pos_probs)
    metrics["log_loss"] = log_loss(y_true, pos_probs, labels=[0,1])
    metrics["brier_score"] = brier_score_loss(y_true, pos_probs)

# Confusion matrix and detailed report
cm = confusion_matrix(y_true, y_pred, labels=[0,1])
report = classification_report(y_true, y_pred, digits=4)

print("Sklearn binary metrics:")
for k, v in metrics.items():
    print(f"{k}: {v:.4f}")
print("\nConfusion matrix:\n", cm)
print("\nClassification report:\n", report)
# Out:
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 63ms/step
# Sklearn binary metrics:
# accuracy: 0.9932
# precision: 1.0000
# recall: 0.7500
# f1: 0.8571
# mcc: 0.8630
# roc_auc: 0.9859
# pr_auc: 0.8333
# log_loss: 0.0639
# brier_score: 0.0070
#
# Confusion matrix:
#  [[142   0]
#  [  1   3]]
#
# Classification report:
#                precision    recall  f1-score   support
#
#            0     0.9930    1.0000    0.9965       142
#            1     1.0000    0.7500    0.8571         4
#
#     accuracy                         0.9932       146
#    macro avg     0.9965    0.8750    0.9268       146
# weighted avg     0.9932    0.9932    0.9927       146
