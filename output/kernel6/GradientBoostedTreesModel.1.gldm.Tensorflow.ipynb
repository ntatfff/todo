# %%
# Import packages and modules
import numpy  as np
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow_decision_forests as tfdf

from sklearn.model_selection import train_test_split
# Out:
# 2026-08-12 05:40:29.862276: I tensorflow/core/util/port.cc:113] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2026-08-12 05:40:30.190674: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2026-08-12 05:40:34.520382: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
# Check the version of TensorFlow Decision Forests
print("Found TensorFlow Decision Forests v" + tfdf.__version__)
# Out:
# Found TensorFlow Decision Forests v1.9.1

# %%
datasetPath = 'dataset/firstorder/kernel5-radius5/dataset.csv'

# %%
# Parameters
datasetPath = "dataset/gldm/kernel6-radius6/1.dataset.csv"

# %%
# train/validation/test = 70/10/20
dataset = pd.read_csv(datasetPath)

train_data, temp_data = train_test_split(dataset, test_size=0.3, random_state=42)
validation_data, test_data = train_test_split(temp_data, test_size=2/3, random_state=42)

# %%
from sklearn.utils.class_weight import compute_class_weight

# tinh class weight tren tap train
classes = np.array([0, 1])
weights = compute_class_weight(class_weight="balanced", classes=classes, y=train_data["label"])
class_weight = {0: weights[0], 1: weights[1]}

# gan sample_weight cho tung dong
train_data["sample_weight"] = train_data["label"].map(class_weight)
validation_data["sample_weight"] = validation_data["label"].map(class_weight)
test_data["sample_weight"] = test_data["label"].map(class_weight)

# Convert the dataset into a TensorFlow dataset.
train_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    train_data, label="label", weight="sample_weight"
)         
val_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    validation_data, label="label", weight="sample_weight"
)
test_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    test_data, label="label", weight="sample_weight"
)
# Out:
# 2026-08-12 05:40:46.756515: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:984] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2026-08-12 05:40:46.757933: W tensorflow/core/common_runtime/gpu/gpu_device.cc:2251] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...

# %%
import keras

# %%
# %%time

# Train a Gradient Boosted Trees model.
model = tfdf.keras.GradientBoostedTreesModel()

# Add evaluation metrics
model.compile(
    metrics=["accuracy"]
)
model.fit(x=train_ds)

# # Train a Gradient Boosted Trees model.
# model = tfdf.keras.GradientBoostedTreesModel(num_trees=1500)
# model.fit(train_ds)
# Out:
# Use /tmp/tmpvrw1224q as temporary training directory
# Reading training dataset...
# [WARNING 26-08-12 05:40:46.8909 UTC gradient_boosted_trees.cc:1840] "goss_alpha" set but "sampling_method" not equal to "GOSS".
# [WARNING 26-08-12 05:40:46.8911 UTC gradient_boosted_trees.cc:1851] "goss_beta" set but "sampling_method" not equal to "GOSS".
# [WARNING 26-08-12 05:40:46.8911 UTC gradient_boosted_trees.cc:1865] "selective_gradient_boosting_ratio" set but "sampling_method" not equal to "SELGB".
# Training dataset read in 0:00:02.358702. Found 450 examples.
# Training model...
# Model trained in 0:00:00.173260
# Compiling model...
# [INFO 26-08-12 05:40:49.4480 UTC kernel.cc:1233] Loading model from path /tmp/tmpvrw1224q/model/ with prefix 947c790be0fd40ca
# [INFO 26-08-12 05:40:49.4497 UTC quick_scorer_extended.cc:911] The binary was compiled without AVX2 support, but your CPU supports it. Enable it for faster model inference.
# [INFO 26-08-12 05:40:49.4498 UTC abstract_model.cc:1362] Engine "GradientBoostedTreesQuickScorerExtended" built
# [INFO 26-08-12 05:40:49.4498 UTC kernel.cc:1061] Use fast generic engine
# Model compiled.
# CPU times: user 5.35 s, sys: 243 ms, total: 5.59 s
# Wall time: 8.12 s

# %%
# Evaluate the model
evaluate = model.evaluate(val_ds, return_dict=True)
print()

for name, value in evaluate.items():
    print(f"{name}: {value:.4f}")
# Out:
# WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 1/1 [==============================] - ETA: 0s - loss: 0.0000e+00 - accuracy: 0.9531
# 1/1 [==============================] - 3s 3s/step - loss: 0.0000e+00 - accuracy: 0.9531
# loss: 0.0000
# accuracy: 0.9531

# %%
# Model Summary
model.summary()
# Out:
# Model: "gradient_boosted_trees_model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
# =================================================================
# Total params: 1 (1.00 Byte)
# Trainable params: 0 (0.00 Byte)
# Non-trainable params: 1 (1.00 Byte)
# _________________________________________________________________
# Type: "GRADIENT_BOOSTED_TREES"
# Task: CLASSIFICATION
# Label: "__LABEL"
#
# Input Features (14):
# 	DependenceEntropy
# 	DependenceNonUniformity
# 	DependenceNonUniformityNormalized
# 	DependenceVariance
# 	GrayLevelNonUniformity
# 	GrayLevelVariance
# 	HighGrayLevelEmphasis
# 	LargeDependenceEmphasis
# 	LargeDependenceHighGrayLevelEmphasis
# 	LargeDependenceLowGrayLevelEmphasis
# 	LowGrayLevelEmphasis
# 	SmallDependenceEmphasis
# 	SmallDependenceHighGrayLevelEmphasis
# 	SmallDependenceLowGrayLevelEmphasis
#
# Trained with weights
#
# Variable Importance: INV_MEAN_MIN_DEPTH:
#     1.                "HighGrayLevelEmphasis"  0.774640 ################
#     2. "LargeDependenceHighGrayLevelEmphasis"  0.383350 #####
#     3.                    "DependenceEntropy"  0.234874 #
#     4.               "GrayLevelNonUniformity"  0.213447
#     5.  "SmallDependenceLowGrayLevelEmphasis"  0.199381
#     6.                    "GrayLevelVariance"  0.197238
#     7.    "DependenceNonUniformityNormalized"  0.194870
#     8.                 "LowGrayLevelEmphasis"  0.193975
#     9.              "LargeDependenceEmphasis"  0.190617
#    10. "SmallDependenceHighGrayLevelEmphasis"  0.190452
#    11.                   "DependenceVariance"  0.188868
#    12.  "LargeDependenceLowGrayLevelEmphasis"  0.188522
#    13.              "SmallDependenceEmphasis"  0.187972
#    14.              "DependenceNonUniformity"  0.187672
#
# Variable Importance: NUM_AS_ROOT:
#     1.                "HighGrayLevelEmphasis" 14.000000 ################
#     2. "LargeDependenceHighGrayLevelEmphasis"  3.000000
#
# Variable Importance: NUM_NODES:
#     1.                "HighGrayLevelEmphasis" 56.000000 ################
#     2. "LargeDependenceHighGrayLevelEmphasis" 46.000000 ############
#     3.                    "DependenceEntropy" 43.000000 ############
#     4.               "GrayLevelNonUniformity" 31.000000 ########
#     5.  "SmallDependenceLowGrayLevelEmphasis" 18.000000 ####
#     6.                    "GrayLevelVariance" 16.000000 ###
#     7. "SmallDependenceHighGrayLevelEmphasis" 15.000000 ###
#     8.    "DependenceNonUniformityNormalized" 14.000000 ###
#     9.                 "LowGrayLevelEmphasis" 14.000000 ###
#    10.              "LargeDependenceEmphasis" 12.000000 ##
#    11.  "LargeDependenceLowGrayLevelEmphasis" 10.000000 ##
#    12.                   "DependenceVariance"  9.000000 #
#    13.              "SmallDependenceEmphasis"  9.000000 #
#    14.              "DependenceNonUniformity"  3.000000
#
# Variable Importance: SUM_SCORE:
#     1.                "HighGrayLevelEmphasis" 336.051778 ################
#     2. "LargeDependenceHighGrayLevelEmphasis" 57.768015 ##
#     3.                    "DependenceEntropy" 36.997311 #
#     4.               "GrayLevelNonUniformity" 34.917037 #
#     5.                    "GrayLevelVariance" 15.674614
#     6.  "SmallDependenceLowGrayLevelEmphasis"  9.610158
#     7.              "SmallDependenceEmphasis"  4.599143
#     8.    "DependenceNonUniformityNormalized"  4.451388
#     9.                   "DependenceVariance"  3.281413
#    10.                 "LowGrayLevelEmphasis"  2.485957
#    11. "SmallDependenceHighGrayLevelEmphasis"  1.849768
#    12.              "LargeDependenceEmphasis"  1.056022
#    13.              "DependenceNonUniformity"  1.045315
#    14.  "LargeDependenceLowGrayLevelEmphasis"  0.040801
#
#
#
# Loss: BINOMIAL_LOG_LIKELIHOOD
# Validation loss value: 0.630221
# Number of trees per iteration: 1
# Node format: NOT_SET
# Number of trees: 17
# Total number of nodes: 609
#
# Number of nodes by tree:
# Count: 17 Average: 35.8235 StdDev: 3.07237
# Min: 31 Max: 39 Ignored: 0
# ----------------------------------------------
# [ 31, 32) 2  11.76%  11.76% ###
# [ 32, 33) 0   0.00%  11.76%
# [ 33, 34) 5  29.41%  41.18% #######
# [ 34, 35) 0   0.00%  41.18%
# [ 35, 36) 1   5.88%  47.06% #
# [ 36, 37) 0   0.00%  47.06%
# [ 37, 38) 2  11.76%  58.82% ###
# [ 38, 39) 0   0.00%  58.82%
# [ 39, 39] 7  41.18% 100.00% ##########
#
# Depth by leafs:
# Count: 313 Average: 4.39936 StdDev: 0.703891
# Min: 2 Max: 5 Ignored: 0
# ----------------------------------------------
# [ 2, 3)   3   0.96%   0.96%
# [ 3, 4)  31   9.90%  10.86% ##
# [ 4, 5) 117  37.38%  48.24% #######
# [ 5, 5] 162  51.76% 100.00% ##########
#
# Number of training obs by leaf:
# Count: 313 Average: 22.1054 StdDev: 56.3684
# Min: 5 Max: 269 Ignored: 0
# ----------------------------------------------
# [   5,  18) 267  85.30%  85.30% ##########
# [  18,  31)  22   7.03%  92.33% #
# [  31,  44)   6   1.92%  94.25%
# [  44,  58)   1   0.32%  94.57%
# [  58,  71)   0   0.00%  94.57%
# [  71,  84)   0   0.00%  94.57%
# [  84,  97)   0   0.00%  94.57%
# [  97, 111)   0   0.00%  94.57%
# [ 111, 124)   0   0.00%  94.57%
# [ 124, 137)   0   0.00%  94.57%
# [ 137, 150)   0   0.00%  94.57%
# [ 150, 164)   0   0.00%  94.57%
# [ 164, 177)   0   0.00%  94.57%
# [ 177, 190)   0   0.00%  94.57%
# [ 190, 203)   0   0.00%  94.57%
# [ 203, 217)   0   0.00%  94.57%
# [ 217, 230)   1   0.32%  94.89%
# [ 230, 243)   2   0.64%  95.53%
# [ 243, 256)   2   0.64%  96.17%
# [ 256, 269]  12   3.83% 100.00%
#
# Attribute in nodes:
# 	56 : HighGrayLevelEmphasis [NUMERICAL]
# 	46 : LargeDependenceHighGrayLevelEmphasis [NUMERICAL]
# 	43 : DependenceEntropy [NUMERICAL]
# 	31 : GrayLevelNonUniformity [NUMERICAL]
# 	18 : SmallDependenceLowGrayLevelEmphasis [NUMERICAL]
# 	16 : GrayLevelVariance [NUMERICAL]
# 	15 : SmallDependenceHighGrayLevelEmphasis [NUMERICAL]
# 	14 : LowGrayLevelEmphasis [NUMERICAL]
# 	14 : DependenceNonUniformityNormalized [NUMERICAL]
# 	12 : LargeDependenceEmphasis [NUMERICAL]
# 	10 : LargeDependenceLowGrayLevelEmphasis [NUMERICAL]
# 	9 : SmallDependenceEmphasis [NUMERICAL]
# 	9 : DependenceVariance [NUMERICAL]
# 	3 : DependenceNonUniformity [NUMERICAL]
#
# Attribute in nodes with depth <= 0:
# 	14 : HighGrayLevelEmphasis [NUMERICAL]
# 	3 : LargeDependenceHighGrayLevelEmphasis [NUMERICAL]
#
# Attribute in nodes with depth <= 1:
# 	22 : LargeDependenceHighGrayLevelEmphasis [NUMERICAL]
# 	19 : HighGrayLevelEmphasis [NUMERICAL]
# 	6 : DependenceEntropy [NUMERICAL]
# 	3 : GrayLevelNonUniformity [NUMERICAL]
# 	1 : LowGrayLevelEmphasis [NUMERICAL]
#
# Attribute in nodes with depth <= 2:
# 	32 : LargeDependenceHighGrayLevelEmphasis [NUMERICAL]
# 	28 : HighGrayLevelEmphasis [NUMERICAL]
# 	17 : DependenceEntropy [NUMERICAL]
# 	13 : GrayLevelNonUniformity [NUMERICAL]
# 	10 : GrayLevelVariance [NUMERICAL]
# 	6 : SmallDependenceLowGrayLevelEmphasis [NUMERICAL]
# 	3 : LargeDependenceEmphasis [NUMERICAL]
# 	2 : SmallDependenceEmphasis [NUMERICAL]
# 	2 : DependenceNonUniformityNormalized [NUMERICAL]
# 	1 : SmallDependenceHighGrayLevelEmphasis [NUMERICAL]
# 	1 : LowGrayLevelEmphasis [NUMERICAL]
# 	1 : DependenceNonUniformity [NUMERICAL]
#
# Attribute in nodes with depth <= 3:
# 	44 : HighGrayLevelEmphasis [NUMERICAL]
# 	38 : LargeDependenceHighGrayLevelEmphasis [NUMERICAL]
# 	37 : DependenceEntropy [NUMERICAL]
# 	29 : GrayLevelNonUniformity [NUMERICAL]
# 	13 : GrayLevelVariance [NUMERICAL]
# 	10 : DependenceNonUniformityNormalized [NUMERICAL]
# 	8 : SmallDependenceLowGrayLevelEmphasis [NUMERICAL]
# 	8 : SmallDependenceHighGrayLevelEmphasis [NUMERICAL]
# 	6 : SmallDependenceEmphasis [NUMERICAL]
# 	6 : DependenceVariance [NUMERICAL]
# 	5 : LowGrayLevelEmphasis [NUMERICAL]
# 	5 : LargeDependenceEmphasis [NUMERICAL]
# 	3 : LargeDependenceLowGrayLevelEmphasis [NUMERICAL]
# 	3 : DependenceNonUniformity [NUMERICAL]
#
# Attribute in nodes with depth <= 5:
# 	56 : HighGrayLevelEmphasis [NUMERICAL]
# 	46 : LargeDependenceHighGrayLevelEmphasis [NUMERICAL]
# 	43 : DependenceEntropy [NUMERICAL]
# 	31 : GrayLevelNonUniformity [NUMERICAL]
# 	18 : SmallDependenceLowGrayLevelEmphasis [NUMERICAL]
# 	16 : GrayLevelVariance [NUMERICAL]
# 	15 : SmallDependenceHighGrayLevelEmphasis [NUMERICAL]
# 	14 : LowGrayLevelEmphasis [NUMERICAL]
# 	14 : DependenceNonUniformityNormalized [NUMERICAL]
# 	12 : LargeDependenceEmphasis [NUMERICAL]
# 	10 : LargeDependenceLowGrayLevelEmphasis [NUMERICAL]
# 	9 : SmallDependenceEmphasis [NUMERICAL]
# 	9 : DependenceVariance [NUMERICAL]
# 	3 : DependenceNonUniformity [NUMERICAL]
#
# Condition type in nodes:
# 	296 : HigherCondition
# Condition type in nodes with depth <= 0:
# 	17 : HigherCondition
# Condition type in nodes with depth <= 1:
# 	51 : HigherCondition
# Condition type in nodes with depth <= 2:
# 	116 : HigherCondition
# Condition type in nodes with depth <= 3:
# 	215 : HigherCondition
# Condition type in nodes with depth <= 5:
# 	296 : HigherCondition
#
# Training logs:
# Number of iteration to final model: 17
# 	Iter:1 train-loss:1.215662 valid-loss:1.240663  train-accuracy:0.961479 valid-accuracy:0.898374
# 	Iter:2 train-loss:1.075709 valid-loss:1.124552  train-accuracy:0.970298 valid-accuracy:0.898374
# 	Iter:3 train-loss:0.954418 valid-loss:1.027871  train-accuracy:0.968872 valid-accuracy:0.898374
# 	Iter:4 train-loss:0.852425 valid-loss:0.952679  train-accuracy:0.974578 valid-accuracy:0.913279
# 	Iter:5 train-loss:0.764862 valid-loss:0.882584  train-accuracy:0.973152 valid-accuracy:0.913279
# 	Iter:6 train-loss:0.689986 valid-loss:0.834097  train-accuracy:0.978599 valid-accuracy:0.913279
# 	Iter:16 train-loss:0.278191 valid-loss:0.634149  train-accuracy:0.990013 valid-accuracy:0.913279
# 	Iter:26 train-loss:0.126571 valid-loss:0.677802  train-accuracy:0.995720 valid-accuracy:0.913279
# 	Iter:36 train-loss:0.062385 valid-loss:0.803241  train-accuracy:0.997147 valid-accuracy:0.913279
# 	Iter:46 train-loss:0.032743 valid-loss:0.949026  train-accuracy:1.000000 valid-accuracy:0.913279

# %%
# Model features
model.make_inspector().features()
# Out:
# ["DependenceEntropy" (1; #0),
#  "DependenceNonUniformity" (1; #1),
#  "DependenceNonUniformityNormalized" (1; #2),
#  "DependenceVariance" (1; #3),
#  "GrayLevelNonUniformity" (1; #4),
#  "GrayLevelVariance" (1; #5),
#  "HighGrayLevelEmphasis" (1; #6),
#  "LargeDependenceEmphasis" (1; #7),
#  "LargeDependenceHighGrayLevelEmphasis" (1; #8),
#  "LargeDependenceLowGrayLevelEmphasis" (1; #9),
#  "LowGrayLevelEmphasis" (1; #10),
#  "SmallDependenceEmphasis" (1; #11),
#  "SmallDependenceHighGrayLevelEmphasis" (1; #12),
#  "SmallDependenceLowGrayLevelEmphasis" (1; #13)]

# %%
# Feature importance
model.make_inspector().variable_importances()
# Out:
# {'INV_MEAN_MIN_DEPTH': [("HighGrayLevelEmphasis" (1; #6), 0.7746402844219422),
#   ("LargeDependenceHighGrayLevelEmphasis" (1; #8), 0.38335000148355264),
#   ("DependenceEntropy" (1; #0), 0.23487400634272462),
#   ("GrayLevelNonUniformity" (1; #4), 0.21344728936811122),
#   ("SmallDependenceLowGrayLevelEmphasis" (1; #13), 0.19938067486297723),
#   ("GrayLevelVariance" (1; #5), 0.19723815102853176),
#   ("DependenceNonUniformityNormalized" (1; #2), 0.19487045012948584),
#   ("LowGrayLevelEmphasis" (1; #10), 0.19397496732224),
#   ("LargeDependenceEmphasis" (1; #7), 0.19061715142610655),
#   ("SmallDependenceHighGrayLevelEmphasis" (1; #12), 0.1904515352551298),
#   ("DependenceVariance" (1; #3), 0.18886846838359744),
#   ("LargeDependenceLowGrayLevelEmphasis" (1; #9), 0.1885222008504938),
#   ("SmallDependenceEmphasis" (1; #11), 0.18797193923822944),
#   ("DependenceNonUniformity" (1; #1), 0.1876720743894446)],
#  'NUM_AS_ROOT': [("HighGrayLevelEmphasis" (1; #6), 14.0),
#   ("LargeDependenceHighGrayLevelEmphasis" (1; #8), 3.0)],
#  'SUM_SCORE': [("HighGrayLevelEmphasis" (1; #6), 336.05177823343155),
#   ("LargeDependenceHighGrayLevelEmphasis" (1; #8), 57.76801465364414),
#   ("DependenceEntropy" (1; #0), 36.9973105537452),
#   ("GrayLevelNonUniformity" (1; #4), 34.91703661932798),
#   ("GrayLevelVariance" (1; #5), 15.674614180761859),
#   ("SmallDependenceLowGrayLevelEmphasis" (1; #13), 9.610157998277614),
#   ("SmallDependenceEmphasis" (1; #11), 4.5991433755518365),
#   ("DependenceNonUniformityNormalized" (1; #2), 4.451388301367466),
#   ("DependenceVariance" (1; #3), 3.2814125240977865),
#   ("LowGrayLevelEmphasis" (1; #10), 2.485956657760674),
#   ("SmallDependenceHighGrayLevelEmphasis" (1; #12), 1.8497684121994151),
#   ("LargeDependenceEmphasis" (1; #7), 1.0560217628220354),
#   ("DependenceNonUniformity" (1; #1), 1.04531514156951),
#   ("LargeDependenceLowGrayLevelEmphasis" (1; #9), 0.04080111483441222)],
#  'NUM_NODES': [("HighGrayLevelEmphasis" (1; #6), 56.0),
#   ("LargeDependenceHighGrayLevelEmphasis" (1; #8), 46.0),
#   ("DependenceEntropy" (1; #0), 43.0),
#   ("GrayLevelNonUniformity" (1; #4), 31.0),
#   ("SmallDependenceLowGrayLevelEmphasis" (1; #13), 18.0),
#   ("GrayLevelVariance" (1; #5), 16.0),
#   ("SmallDependenceHighGrayLevelEmphasis" (1; #12), 15.0),
#   ("DependenceNonUniformityNormalized" (1; #2), 14.0),
#   ("LowGrayLevelEmphasis" (1; #10), 14.0),
#   ("LargeDependenceEmphasis" (1; #7), 12.0),
#   ("LargeDependenceLowGrayLevelEmphasis" (1; #9), 10.0),
#   ("DependenceVariance" (1; #3), 9.0),
#   ("SmallDependenceEmphasis" (1; #11), 9.0),
#   ("DependenceNonUniformity" (1; #1), 3.0)]}

# %%
# Model self evaluation
model.make_inspector().evaluation()
# Out:
# Evaluation(num_examples=None, accuracy=0.913279116153717, loss=0.6302214860916138, rmse=None, ndcg=None, aucs=None, auuc=None, qini=None)

# %%
logs = model.make_inspector().training_logs()

plt.figure(figsize=(12, 4))
plt.subplot(1, 2, 1)
plt.plot([log.num_trees for log in logs], [log.evaluation.accuracy for log in logs])
plt.xlabel("Number of trees")
plt.ylabel("Accuracy (out-of-bag)")
plt.subplot(1, 2, 2)
plt.plot([log.num_trees for log in logs], [log.evaluation.loss for log in logs])
plt.xlabel("Number of trees")
plt.ylabel("Logloss (out-of-bag)")
plt.show()

# %% [markdown]
# Calculate the score of our hold-out validation dataset

# %%
predictions = model.predict(val_ds)
y_true      = validation_data["label"]

from sklearn.metrics import roc_auc_score
ROC_AUC = roc_auc_score(y_true, predictions)
print("The ROC AUC score is %.5f" % ROC_AUC )
# Out:
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 56ms/step
# The ROC AUC score is 0.98889

# %%
# Compute binary classification metrics with sklearn
import numpy as np
from sklearn.metrics import (
    accuracy_score,
    precision_score,
    recall_score,
    f1_score,
    roc_auc_score,
    average_precision_score,
    confusion_matrix,
    classification_report,
    matthews_corrcoef,
    log_loss,
    brier_score_loss,
)

# Get predictions (probabilities or class labels)
preds = model.predict(test_ds)
# If model outputs probabilities, convert to labels by threshold 0.5
if preds.ndim == 2:
    # For TFDF classification, preds may be class probabilities with shape (N, 2)
    if preds.shape[1] == 2:
        pos_probs = preds[:, 1]
    else:
        # If single-probability column (positive class)
        pos_probs = preds[:, -1]
    y_pred = (pos_probs >= 0.5).astype(int)
else:
    # Already class labels
    y_pred = preds.astype(int)
    pos_probs = None

# Ground truth labels (must be 0/1 integers)
y_true = test_data["label"].astype(int).to_numpy()

# Core metrics
metrics = {}
metrics["accuracy"] = accuracy_score(y_true, y_pred)
metrics["precision"] = precision_score(y_true, y_pred, zero_division=0)
metrics["recall"] = recall_score(y_true, y_pred, zero_division=0)
metrics["f1"] = f1_score(y_true, y_pred, zero_division=0)
metrics["mcc"] = matthews_corrcoef(y_true, y_pred)

# Probabilistic metrics (only if we have probabilities)
if pos_probs is not None:
    metrics["roc_auc"] = roc_auc_score(y_true, pos_probs)
    metrics["pr_auc"] = average_precision_score(y_true, pos_probs)
    metrics["log_loss"] = log_loss(y_true, pos_probs, labels=[0,1])
    metrics["brier_score"] = brier_score_loss(y_true, pos_probs)

# Confusion matrix and detailed report
cm = confusion_matrix(y_true, y_pred, labels=[0,1])
report = classification_report(y_true, y_pred, digits=4)

print("Sklearn binary metrics:")
for k, v in metrics.items():
    print(f"{k}: {v:.4f}")
print("\nConfusion matrix:\n", cm)
print("\nClassification report:\n", report)
# Out:
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 63ms/step
# Sklearn binary metrics:
# accuracy: 0.9147
# precision: 0.5714
# recall: 0.8571
# f1: 0.6857
# mcc: 0.6562
# roc_auc: 0.9783
# pr_auc: 0.8556
# log_loss: 0.2068
# brier_score: 0.0518
#
# Confusion matrix:
#  [[106   9]
#  [  2  12]]
#
# Classification report:
#                precision    recall  f1-score   support
#
#            0     0.9815    0.9217    0.9507       115
#            1     0.5714    0.8571    0.6857        14
#
#     accuracy                         0.9147       129
#    macro avg     0.7765    0.8894    0.8182       129
# weighted avg     0.9370    0.9147    0.9219       129
