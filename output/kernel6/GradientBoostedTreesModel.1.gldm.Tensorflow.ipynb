# %%
# Import packages and modules
import numpy  as np
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow_decision_forests as tfdf

from sklearn.model_selection import train_test_split
# Out:
# 2026-08-15 05:06:34.695900: I tensorflow/core/util/port.cc:113] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2026-08-15 05:06:35.045055: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2026-08-15 05:06:39.821992: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
# Check the version of TensorFlow Decision Forests
print("Found TensorFlow Decision Forests v" + tfdf.__version__)
# Out:
# Found TensorFlow Decision Forests v1.9.1

# %%
datasetPath = 'dataset/firstorder/kernel5/dataset.csv'

# %%
# Parameters
datasetPath = "dataset/gldm/kernel6/1.dataset.csv"

# %%
# train/validation/test = 70/10/20
dataset = pd.read_csv(datasetPath)

train_data, temp_data = train_test_split(dataset, test_size=0.3, random_state=42)
validation_data, test_data = train_test_split(temp_data, test_size=2/3, random_state=42)

# %%
from sklearn.utils.class_weight import compute_class_weight

# tinh class weight tren tap train
classes = np.array([0, 1])
weights = compute_class_weight(class_weight="balanced", classes=classes, y=train_data["label"])
class_weight = {0: weights[0], 1: weights[1]}

# gan sample_weight cho tung dong
train_data["sample_weight"] = train_data["label"].map(class_weight)
validation_data["sample_weight"] = validation_data["label"].map(class_weight)
test_data["sample_weight"] = test_data["label"].map(class_weight)

# Convert the dataset into a TensorFlow dataset.
train_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    train_data, label="label", weight="sample_weight"
)         
val_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    validation_data, label="label", weight="sample_weight"
)
test_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    test_data, label="label", weight="sample_weight"
)
# Out:
# 2026-08-15 05:06:53.619166: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:984] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2026-08-15 05:06:53.620836: W tensorflow/core/common_runtime/gpu/gpu_device.cc:2251] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...

# %%
import keras

# %%
# %%time

# Train a Gradient Boosted Trees model.
model = tfdf.keras.GradientBoostedTreesModel()

# Add evaluation metrics
model.compile(
    metrics=["accuracy"]
)
model.fit(x=train_ds)

# # Train a Gradient Boosted Trees model.
# model = tfdf.keras.GradientBoostedTreesModel(num_trees=1500)
# model.fit(train_ds)
# Out:
# Use /tmp/tmph30akb5u as temporary training directory
# Reading training dataset...
# [WARNING 26-08-15 05:06:53.7680 UTC gradient_boosted_trees.cc:1840] "goss_alpha" set but "sampling_method" not equal to "GOSS".
# [WARNING 26-08-15 05:06:53.7682 UTC gradient_boosted_trees.cc:1851] "goss_beta" set but "sampling_method" not equal to "GOSS".
# [WARNING 26-08-15 05:06:53.7682 UTC gradient_boosted_trees.cc:1865] "selective_gradient_boosting_ratio" set but "sampling_method" not equal to "SELGB".
# Training dataset read in 0:00:02.556678. Found 507 examples.
# Training model...
# Model trained in 0:00:00.133793
# Compiling model...
# [INFO 26-08-15 05:06:56.4888 UTC kernel.cc:1233] Loading model from path /tmp/tmph30akb5u/model/ with prefix 12a97725d6cd4d94
# [INFO 26-08-15 05:06:56.4902 UTC quick_scorer_extended.cc:911] The binary was compiled without AVX2 support, but your CPU supports it. Enable it for faster model inference.
# [INFO 26-08-15 05:06:56.4903 UTC abstract_model.cc:1362] Engine "GradientBoostedTreesQuickScorerExtended" built
# [INFO 26-08-15 05:06:56.4903 UTC kernel.cc:1061] Use fast generic engine
# Model compiled.
# CPU times: user 5.38 s, sys: 231 ms, total: 5.61 s
# Wall time: 5.85 s

# %%
# Evaluate the model
evaluate = model.evaluate(val_ds, return_dict=True)
print()

for name, value in evaluate.items():
    print(f"{name}: {value:.4f}")
# Out:
# WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 1/1 [==============================] - ETA: 0s - loss: 0.0000e+00 - accuracy: 0.9583
# 1/1 [==============================] - 3s 3s/step - loss: 0.0000e+00 - accuracy: 0.9583
# loss: 0.0000
# accuracy: 0.9583

# %%
# Model Summary
model.summary()
# Out:
# Model: "gradient_boosted_trees_model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
# =================================================================
# Total params: 1 (1.00 Byte)
# Trainable params: 0 (0.00 Byte)
# Non-trainable params: 1 (1.00 Byte)
# _________________________________________________________________
# Type: "GRADIENT_BOOSTED_TREES"
# Task: CLASSIFICATION
# Label: "__LABEL"
#
# Input Features (14):
# 	DependenceEntropy
# 	DependenceNonUniformity
# 	DependenceNonUniformityNormalized
# 	DependenceVariance
# 	GrayLevelNonUniformity
# 	GrayLevelVariance
# 	HighGrayLevelEmphasis
# 	LargeDependenceEmphasis
# 	LargeDependenceHighGrayLevelEmphasis
# 	LargeDependenceLowGrayLevelEmphasis
# 	LowGrayLevelEmphasis
# 	SmallDependenceEmphasis
# 	SmallDependenceHighGrayLevelEmphasis
# 	SmallDependenceLowGrayLevelEmphasis
#
# Trained with weights
#
# Variable Importance: INV_MEAN_MIN_DEPTH:
#     1. "SmallDependenceHighGrayLevelEmphasis"  1.000000 ################
#     2.                "HighGrayLevelEmphasis"  0.298091 #
#     3.                 "LowGrayLevelEmphasis"  0.285396 #
#     4.              "SmallDependenceEmphasis"  0.281523 #
#     5.  "SmallDependenceLowGrayLevelEmphasis"  0.262520
#     6.                    "DependenceEntropy"  0.247121
#     7.  "LargeDependenceLowGrayLevelEmphasis"  0.246123
#     8.               "GrayLevelNonUniformity"  0.241711
#     9. "LargeDependenceHighGrayLevelEmphasis"  0.240663
#    10.                    "GrayLevelVariance"  0.234679
#    11.              "DependenceNonUniformity"  0.233359
#    12.    "DependenceNonUniformityNormalized"  0.233359
#
# Variable Importance: NUM_AS_ROOT:
#     1. "SmallDependenceHighGrayLevelEmphasis" 11.000000
#
# Variable Importance: NUM_NODES:
#     1.                "HighGrayLevelEmphasis" 17.000000 ################
#     2. "SmallDependenceHighGrayLevelEmphasis" 16.000000 ###############
#     3.              "SmallDependenceEmphasis" 12.000000 ###########
#     4.                 "LowGrayLevelEmphasis"  8.000000 #######
#     5.  "LargeDependenceLowGrayLevelEmphasis"  6.000000 #####
#     6.  "SmallDependenceLowGrayLevelEmphasis"  6.000000 #####
#     7.                    "DependenceEntropy"  4.000000 ###
#     8. "LargeDependenceHighGrayLevelEmphasis"  3.000000 ##
#     9.               "GrayLevelNonUniformity"  2.000000 #
#    10.                    "GrayLevelVariance"  2.000000 #
#    11.              "DependenceNonUniformity"  1.000000
#    12.    "DependenceNonUniformityNormalized"  1.000000
#
# Variable Importance: SUM_SCORE:
#     1. "SmallDependenceHighGrayLevelEmphasis" 498.667450 ################
#     2.                "HighGrayLevelEmphasis" 25.457743
#     3.                 "LowGrayLevelEmphasis"  2.221287
#     4.               "GrayLevelNonUniformity"  0.745816
#     5.  "SmallDependenceLowGrayLevelEmphasis"  0.230962
#     6.              "SmallDependenceEmphasis"  0.068839
#     7.                    "DependenceEntropy"  0.032776
#     8. "LargeDependenceHighGrayLevelEmphasis"  0.000105
#     9.  "LargeDependenceLowGrayLevelEmphasis"  0.000102
#    10.                    "GrayLevelVariance"  0.000041
#    11.              "DependenceNonUniformity"  0.000000
#    12.    "DependenceNonUniformityNormalized"  0.000000
#
#
#
# Loss: BINOMIAL_LOG_LIKELIHOOD
# Validation loss value: 1.28716
# Number of trees per iteration: 1
# Node format: NOT_SET
# Number of trees: 11
# Total number of nodes: 167
#
# Number of nodes by tree:
# Count: 11 Average: 15.1818 StdDev: 2.62222
# Min: 11 Max: 21 Ignored: 0
# ----------------------------------------------
# [ 11, 12) 2  18.18%  18.18% ###
# [ 12, 13) 0   0.00%  18.18%
# [ 13, 14) 0   0.00%  18.18%
# [ 14, 15) 0   0.00%  18.18%
# [ 15, 16) 6  54.55%  72.73% ##########
# [ 16, 17) 0   0.00%  72.73%
# [ 17, 18) 2  18.18%  90.91% ###
# [ 18, 19) 0   0.00%  90.91%
# [ 19, 20) 0   0.00%  90.91%
# [ 20, 21) 0   0.00%  90.91%
# [ 21, 21] 1   9.09% 100.00% ##
#
# Depth by leafs:
# Count: 89 Average: 3.35955 StdDev: 1.05199
# Min: 2 Max: 5 Ignored: 0
# ----------------------------------------------
# [ 2, 3) 21  23.60%  23.60% ######
# [ 3, 4) 33  37.08%  60.67% ##########
# [ 4, 5) 17  19.10%  79.78% #####
# [ 5, 5] 18  20.22% 100.00% #####
#
# Number of training obs by leaf:
# Count: 89 Average: 56.6067 StdDev: 124.259
# Min: 5 Max: 410 Ignored: 0
# ----------------------------------------------
# [   5,  25) 75  84.27%  84.27% ##########
# [  25,  45)  0   0.00%  84.27%
# [  45,  65)  0   0.00%  84.27%
# [  65,  86)  2   2.25%  86.52%
# [  86, 106)  0   0.00%  86.52%
# [ 106, 126)  0   0.00%  86.52%
# [ 126, 147)  1   1.12%  87.64%
# [ 147, 167)  0   0.00%  87.64%
# [ 167, 187)  0   0.00%  87.64%
# [ 187, 208)  0   0.00%  87.64%
# [ 208, 228)  0   0.00%  87.64%
# [ 228, 248)  0   0.00%  87.64%
# [ 248, 268)  0   0.00%  87.64%
# [ 268, 289)  1   1.12%  88.76%
# [ 289, 309)  0   0.00%  88.76%
# [ 309, 329)  0   0.00%  88.76%
# [ 329, 350)  1   1.12%  89.89%
# [ 350, 370)  1   1.12%  91.01%
# [ 370, 390)  1   1.12%  92.13%
# [ 390, 410]  7   7.87% 100.00% #
#
# Attribute in nodes:
# 	17 : HighGrayLevelEmphasis [NUMERICAL]
# 	16 : SmallDependenceHighGrayLevelEmphasis [NUMERICAL]
# 	12 : SmallDependenceEmphasis [NUMERICAL]
# 	8 : LowGrayLevelEmphasis [NUMERICAL]
# 	6 : SmallDependenceLowGrayLevelEmphasis [NUMERICAL]
# 	6 : LargeDependenceLowGrayLevelEmphasis [NUMERICAL]
# 	4 : DependenceEntropy [NUMERICAL]
# 	3 : LargeDependenceHighGrayLevelEmphasis [NUMERICAL]
# 	2 : GrayLevelVariance [NUMERICAL]
# 	2 : GrayLevelNonUniformity [NUMERICAL]
# 	1 : DependenceNonUniformityNormalized [NUMERICAL]
# 	1 : DependenceNonUniformity [NUMERICAL]
#
# Attribute in nodes with depth <= 0:
# 	11 : SmallDependenceHighGrayLevelEmphasis [NUMERICAL]
#
# Attribute in nodes with depth <= 1:
# 	11 : SmallDependenceHighGrayLevelEmphasis [NUMERICAL]
# 	9 : HighGrayLevelEmphasis [NUMERICAL]
# 	5 : LowGrayLevelEmphasis [NUMERICAL]
# 	4 : SmallDependenceLowGrayLevelEmphasis [NUMERICAL]
# 	2 : SmallDependenceEmphasis [NUMERICAL]
# 	1 : GrayLevelNonUniformity [NUMERICAL]
# 	1 : DependenceEntropy [NUMERICAL]
#
# Attribute in nodes with depth <= 2:
# 	15 : SmallDependenceHighGrayLevelEmphasis [NUMERICAL]
# 	12 : HighGrayLevelEmphasis [NUMERICAL]
# 	7 : SmallDependenceEmphasis [NUMERICAL]
# 	7 : LowGrayLevelEmphasis [NUMERICAL]
# 	5 : SmallDependenceLowGrayLevelEmphasis [NUMERICAL]
# 	2 : LargeDependenceHighGrayLevelEmphasis [NUMERICAL]
# 	2 : GrayLevelNonUniformity [NUMERICAL]
# 	2 : DependenceEntropy [NUMERICAL]
# 	1 : LargeDependenceLowGrayLevelEmphasis [NUMERICAL]
# 	1 : GrayLevelVariance [NUMERICAL]
# 	1 : DependenceNonUniformityNormalized [NUMERICAL]
# 	1 : DependenceNonUniformity [NUMERICAL]
#
# Attribute in nodes with depth <= 3:
# 	16 : SmallDependenceHighGrayLevelEmphasis [NUMERICAL]
# 	15 : HighGrayLevelEmphasis [NUMERICAL]
# 	10 : SmallDependenceEmphasis [NUMERICAL]
# 	8 : LowGrayLevelEmphasis [NUMERICAL]
# 	5 : SmallDependenceLowGrayLevelEmphasis [NUMERICAL]
# 	4 : LargeDependenceLowGrayLevelEmphasis [NUMERICAL]
# 	3 : LargeDependenceHighGrayLevelEmphasis [NUMERICAL]
# 	3 : DependenceEntropy [NUMERICAL]
# 	2 : GrayLevelNonUniformity [NUMERICAL]
# 	1 : GrayLevelVariance [NUMERICAL]
# 	1 : DependenceNonUniformityNormalized [NUMERICAL]
# 	1 : DependenceNonUniformity [NUMERICAL]
#
# Attribute in nodes with depth <= 5:
# 	17 : HighGrayLevelEmphasis [NUMERICAL]
# 	16 : SmallDependenceHighGrayLevelEmphasis [NUMERICAL]
# 	12 : SmallDependenceEmphasis [NUMERICAL]
# 	8 : LowGrayLevelEmphasis [NUMERICAL]
# 	6 : SmallDependenceLowGrayLevelEmphasis [NUMERICAL]
# 	6 : LargeDependenceLowGrayLevelEmphasis [NUMERICAL]
# 	4 : DependenceEntropy [NUMERICAL]
# 	3 : LargeDependenceHighGrayLevelEmphasis [NUMERICAL]
# 	2 : GrayLevelVariance [NUMERICAL]
# 	2 : GrayLevelNonUniformity [NUMERICAL]
# 	1 : DependenceNonUniformityNormalized [NUMERICAL]
# 	1 : DependenceNonUniformity [NUMERICAL]
#
# Condition type in nodes:
# 	78 : HigherCondition
# Condition type in nodes with depth <= 0:
# 	11 : HigherCondition
# Condition type in nodes with depth <= 1:
# 	33 : HigherCondition
# Condition type in nodes with depth <= 2:
# 	56 : HigherCondition
# Condition type in nodes with depth <= 3:
# 	69 : HigherCondition
# Condition type in nodes with depth <= 5:
# 	78 : HigherCondition
#
# Training logs:
# Number of iteration to final model: 11
# 	Iter:1 train-loss:1.202314 valid-loss:1.321912  train-accuracy:0.990537 valid-accuracy:0.723553
# 	Iter:2 train-loss:1.051796 valid-loss:1.276246  train-accuracy:0.990537 valid-accuracy:0.723553
# 	Iter:3 train-loss:0.926351 valid-loss:1.246905  train-accuracy:0.990537 valid-accuracy:0.723553
# 	Iter:4 train-loss:0.820400 valid-loss:1.230408  train-accuracy:0.990537 valid-accuracy:0.723553
# 	Iter:5 train-loss:0.729989 valid-loss:1.224184  train-accuracy:0.990537 valid-accuracy:0.723553
# 	Iter:6 train-loss:0.652199 valid-loss:1.226348  train-accuracy:0.990537 valid-accuracy:0.723553
# 	Iter:16 train-loss:0.239164 valid-loss:1.324991  train-accuracy:0.991719 valid-accuracy:0.723553
# 	Iter:26 train-loss:0.097268 valid-loss:1.544818  train-accuracy:0.996451 valid-accuracy:0.723553
# 	Iter:36 train-loss:0.041704 valid-loss:2.196760  train-accuracy:0.997634 valid-accuracy:0.723553

# %%
# Model features
model.make_inspector().features()
# Out:
# ["DependenceEntropy" (1; #0),
#  "DependenceNonUniformity" (1; #1),
#  "DependenceNonUniformityNormalized" (1; #2),
#  "DependenceVariance" (1; #3),
#  "GrayLevelNonUniformity" (1; #4),
#  "GrayLevelVariance" (1; #5),
#  "HighGrayLevelEmphasis" (1; #6),
#  "LargeDependenceEmphasis" (1; #7),
#  "LargeDependenceHighGrayLevelEmphasis" (1; #8),
#  "LargeDependenceLowGrayLevelEmphasis" (1; #9),
#  "LowGrayLevelEmphasis" (1; #10),
#  "SmallDependenceEmphasis" (1; #11),
#  "SmallDependenceHighGrayLevelEmphasis" (1; #12),
#  "SmallDependenceLowGrayLevelEmphasis" (1; #13)]

# %%
# Feature importance
model.make_inspector().variable_importances()
# Out:
# {'INV_MEAN_MIN_DEPTH': [("SmallDependenceHighGrayLevelEmphasis" (1; #12), 1.0),
#   ("HighGrayLevelEmphasis" (1; #6), 0.2980907411209197),
#   ("LowGrayLevelEmphasis" (1; #10), 0.2853960558212671),
#   ("SmallDependenceEmphasis" (1; #11), 0.28152265236217927),
#   ("SmallDependenceLowGrayLevelEmphasis" (1; #13), 0.26252033990236845),
#   ("DependenceEntropy" (1; #0), 0.2471208940829409),
#   ("LargeDependenceLowGrayLevelEmphasis" (1; #9), 0.24612255275870837),
#   ("GrayLevelNonUniformity" (1; #4), 0.24171128929334407),
#   ("LargeDependenceHighGrayLevelEmphasis" (1; #8), 0.24066298342541437),
#   ("GrayLevelVariance" (1; #5), 0.2346793093230612),
#   ("DependenceNonUniformity" (1; #1), 0.23335922642166446),
#   ("DependenceNonUniformityNormalized" (1; #2), 0.23335922642166446)],
#  'SUM_SCORE': [("SmallDependenceHighGrayLevelEmphasis" (1; #12),
#    498.6674497036249),
#   ("HighGrayLevelEmphasis" (1; #6), 25.45774311720845),
#   ("LowGrayLevelEmphasis" (1; #10), 2.221287219420823),
#   ("GrayLevelNonUniformity" (1; #4), 0.7458156766660473),
#   ("SmallDependenceLowGrayLevelEmphasis" (1; #13), 0.23096227513002057),
#   ("SmallDependenceEmphasis" (1; #11), 0.06883857246634052),
#   ("DependenceEntropy" (1; #0), 0.0327760571557974),
#   ("LargeDependenceHighGrayLevelEmphasis" (1; #8), 0.00010520664895276809),
#   ("LargeDependenceLowGrayLevelEmphasis" (1; #9), 0.00010166907739639556),
#   ("GrayLevelVariance" (1; #5), 4.106528367782807e-05),
#   ("DependenceNonUniformity" (1; #1), 2.6645352410711297e-15),
#   ("DependenceNonUniformityNormalized" (1; #2), 2.6090241910707493e-15)],
#  'NUM_AS_ROOT': [("SmallDependenceHighGrayLevelEmphasis" (1; #12), 11.0)],
#  'NUM_NODES': [("HighGrayLevelEmphasis" (1; #6), 17.0),
#   ("SmallDependenceHighGrayLevelEmphasis" (1; #12), 16.0),
#   ("SmallDependenceEmphasis" (1; #11), 12.0),
#   ("LowGrayLevelEmphasis" (1; #10), 8.0),
#   ("LargeDependenceLowGrayLevelEmphasis" (1; #9), 6.0),
#   ("SmallDependenceLowGrayLevelEmphasis" (1; #13), 6.0),
#   ("DependenceEntropy" (1; #0), 4.0),
#   ("LargeDependenceHighGrayLevelEmphasis" (1; #8), 3.0),
#   ("GrayLevelNonUniformity" (1; #4), 2.0),
#   ("GrayLevelVariance" (1; #5), 2.0),
#   ("DependenceNonUniformity" (1; #1), 1.0),
#   ("DependenceNonUniformityNormalized" (1; #2), 1.0)]}

# %%
# Model self evaluation
model.make_inspector().evaluation()
# Out:
# Evaluation(num_examples=None, accuracy=0.723553478717804, loss=1.2871571779251099, rmse=None, ndcg=None, aucs=None, auuc=None, qini=None)

# %%
logs = model.make_inspector().training_logs()

plt.figure(figsize=(12, 4))
plt.subplot(1, 2, 1)
plt.plot([log.num_trees for log in logs], [log.evaluation.accuracy for log in logs])
plt.xlabel("Number of trees")
plt.ylabel("Accuracy (out-of-bag)")
plt.subplot(1, 2, 2)
plt.plot([log.num_trees for log in logs], [log.evaluation.loss for log in logs])
plt.xlabel("Number of trees")
plt.ylabel("Logloss (out-of-bag)")
plt.show()

# %% [markdown]
# Calculate the score of our hold-out validation dataset

# %%
predictions = model.predict(val_ds)
y_true      = validation_data["label"]

from sklearn.metrics import roc_auc_score
ROC_AUC = roc_auc_score(y_true, predictions)
print("The ROC AUC score is %.5f" % ROC_AUC )
# Out:
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 56ms/step
# The ROC AUC score is 1.00000

# %%
# Compute binary classification metrics with sklearn
import numpy as np
from sklearn.metrics import (
    accuracy_score,
    precision_score,
    recall_score,
    f1_score,
    roc_auc_score,
    average_precision_score,
    confusion_matrix,
    classification_report,
    matthews_corrcoef,
    log_loss,
    brier_score_loss,
)

# Get predictions (probabilities or class labels)
preds = model.predict(test_ds)
# If model outputs probabilities, convert to labels by threshold 0.5
if preds.ndim == 2:
    # For TFDF classification, preds may be class probabilities with shape (N, 2)
    if preds.shape[1] == 2:
        pos_probs = preds[:, 1]
    else:
        # If single-probability column (positive class)
        pos_probs = preds[:, -1]
    y_pred = (pos_probs >= 0.5).astype(int)
else:
    # Already class labels
    y_pred = preds.astype(int)
    pos_probs = None

# Ground truth labels (must be 0/1 integers)
y_true = test_data["label"].astype(int).to_numpy()

# Core metrics
metrics = {}
metrics["accuracy"] = accuracy_score(y_true, y_pred)
metrics["precision"] = precision_score(y_true, y_pred, zero_division=0)
metrics["recall"] = recall_score(y_true, y_pred, zero_division=0)
metrics["f1"] = f1_score(y_true, y_pred, zero_division=0)
metrics["mcc"] = matthews_corrcoef(y_true, y_pred)

# Probabilistic metrics (only if we have probabilities)
if pos_probs is not None:
    metrics["roc_auc"] = roc_auc_score(y_true, pos_probs)
    metrics["pr_auc"] = average_precision_score(y_true, pos_probs)
    metrics["log_loss"] = log_loss(y_true, pos_probs, labels=[0,1])
    metrics["brier_score"] = brier_score_loss(y_true, pos_probs)

# Confusion matrix and detailed report
cm = confusion_matrix(y_true, y_pred, labels=[0,1])
report = classification_report(y_true, y_pred, digits=4)

print("Sklearn binary metrics:")
for k, v in metrics.items():
    print(f"{k}: {v:.4f}")
print("\nConfusion matrix:\n", cm)
print("\nClassification report:\n", report)
# Out:
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 65ms/step
# Sklearn binary metrics:
# accuracy: 0.9452
# precision: 0.3000
# recall: 0.7500
# f1: 0.4286
# mcc: 0.4528
# roc_auc: 0.9842
# pr_auc: 0.8167
# log_loss: 0.2290
# brier_score: 0.0493
#
# Confusion matrix:
#  [[135   7]
#  [  1   3]]
#
# Classification report:
#                precision    recall  f1-score   support
#
#            0     0.9926    0.9507    0.9712       142
#            1     0.3000    0.7500    0.4286         4
#
#     accuracy                         0.9452       146
#    macro avg     0.6463    0.8504    0.6999       146
# weighted avg     0.9737    0.9452    0.9564       146
