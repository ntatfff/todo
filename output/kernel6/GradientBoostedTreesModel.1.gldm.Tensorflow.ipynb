# %%
# Import packages and modules
import numpy  as np
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow_decision_forests as tfdf

from sklearn.model_selection import train_test_split
# Out:
# 2026-08-10 17:15:24.271538: I tensorflow/core/util/port.cc:113] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2026-08-10 17:15:24.649121: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2026-08-10 17:15:31.032581: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
# Check the version of TensorFlow Decision Forests
print("Found TensorFlow Decision Forests v" + tfdf.__version__)
# Out:
# Found TensorFlow Decision Forests v1.9.1

# %%
datasetPath = 'dataset/firstorder/kernel5-radius5/dataset.csv'

# %%
# Parameters
datasetPath = "dataset/gldm/kernel6-radius6/dataset.1p.csv"

# %%
# train/validation/test = 70/10/20
dataset = pd.read_csv(datasetPath)

train_data, temp_data = train_test_split(dataset, test_size=0.3, random_state=42)
validation_data, test_data = train_test_split(temp_data, test_size=2/3, random_state=42)

# %%
from sklearn.utils.class_weight import compute_class_weight

# tinh class weight tren tap train
classes = np.array([0, 1])
weights = compute_class_weight(class_weight="balanced", classes=classes, y=train_data["label"])
class_weight = {0: weights[0], 1: weights[1]}

# gan sample_weight cho tung dong
train_data["sample_weight"] = train_data["label"].map(class_weight)
validation_data["sample_weight"] = validation_data["label"].map(class_weight)
test_data["sample_weight"] = test_data["label"].map(class_weight)

# Convert the dataset into a TensorFlow dataset.
train_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    train_data, label="label", weight="sample_weight"
)         
val_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    validation_data, label="label", weight="sample_weight"
)
test_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    test_data, label="label", weight="sample_weight"
)
# Out:
# 2026-08-10 17:15:43.961171: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:984] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2026-08-10 17:15:43.962574: W tensorflow/core/common_runtime/gpu/gpu_device.cc:2251] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...

# %%
import keras

# %%
# %%time

# Train a Gradient Boosted Trees model.
model = tfdf.keras.GradientBoostedTreesModel()

# Add evaluation metrics
model.compile(
    metrics=["accuracy"]
)
model.fit(x=train_ds)

# # Train a Gradient Boosted Trees model.
# model = tfdf.keras.GradientBoostedTreesModel(num_trees=1500)
# model.fit(train_ds)
# Out:
# Use /tmp/tmpucqqzx1y as temporary training directory
# Reading training dataset...
# [WARNING 26-08-10 17:15:44.1430 UTC gradient_boosted_trees.cc:1840] "goss_alpha" set but "sampling_method" not equal to "GOSS".
# [WARNING 26-08-10 17:15:44.1433 UTC gradient_boosted_trees.cc:1851] "goss_beta" set but "sampling_method" not equal to "GOSS".
# [WARNING 26-08-10 17:15:44.1433 UTC gradient_boosted_trees.cc:1865] "selective_gradient_boosting_ratio" set but "sampling_method" not equal to "SELGB".
# Training dataset read in 0:00:02.720196. Found 777 examples.
# Training model...
# Model trained in 0:00:01.508748
# Compiling model...
# [INFO 26-08-10 17:15:48.3977 UTC kernel.cc:1233] Loading model from path /tmp/tmpucqqzx1y/model/ with prefix b67fb6cdeeff4fe6
# [INFO 26-08-10 17:15:48.4074 UTC quick_scorer_extended.cc:911] The binary was compiled without AVX2 support, but your CPU supports it. Enable it for faster model inference.
# [INFO 26-08-10 17:15:48.4081 UTC abstract_model.cc:1362] Engine "GradientBoostedTreesQuickScorerExtended" built
# [INFO 26-08-10 17:15:48.4081 UTC kernel.cc:1061] Use fast generic engine
# Model compiled.
# CPU times: user 7.64 s, sys: 2.14 s, total: 9.78 s
# Wall time: 7.58 s

# %%
# Evaluate the model
evaluate = model.evaluate(val_ds, return_dict=True)
print()

for name, value in evaluate.items():
    print(f"{name}: {value:.4f}")
# Out:
# WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 1/1 [==============================] - ETA: 0s - loss: 0.0000e+00 - accuracy: 1.0000
# 1/1 [==============================] - 3s 3s/step - loss: 0.0000e+00 - accuracy: 1.0000
# loss: 0.0000
# accuracy: 1.0000

# %%
# Model Summary
model.summary()
# Out:
# Model: "gradient_boosted_trees_model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
# =================================================================
# Total params: 1 (1.00 Byte)
# Trainable params: 0 (0.00 Byte)
# Non-trainable params: 1 (1.00 Byte)
# _________________________________________________________________
# Type: "GRADIENT_BOOSTED_TREES"
# Task: CLASSIFICATION
# Label: "__LABEL"
#
# Input Features (32):
# 	10Percentile
# 	90Percentile
# 	DependenceEntropy
# 	DependenceNonUniformity
# 	DependenceNonUniformityNormalized
# 	DependenceVariance
# 	Energy
# 	Entropy
# 	GrayLevelNonUniformity
# 	GrayLevelVariance
# 	HighGrayLevelEmphasis
# 	InterquartileRange
# 	Kurtosis
# 	LargeDependenceEmphasis
# 	LargeDependenceHighGrayLevelEmphasis
# 	LargeDependenceLowGrayLevelEmphasis
# 	LowGrayLevelEmphasis
# 	Maximum
# 	Mean
# 	MeanAbsoluteDeviation
# 	Median
# 	Minimum
# 	Range
# 	RobustMeanAbsoluteDeviation
# 	RootMeanSquared
# 	Skewness
# 	SmallDependenceEmphasis
# 	SmallDependenceHighGrayLevelEmphasis
# 	SmallDependenceLowGrayLevelEmphasis
# 	TotalEnergy
# 	Uniformity
# 	Variance
#
# Trained with weights
#
# Variable Importance: INV_MEAN_MIN_DEPTH:
#     1.  "LargeDependenceLowGrayLevelEmphasis"  0.416051 ################
#     2.                   "DependenceVariance"  0.318706 ########
#     3.                "HighGrayLevelEmphasis"  0.254611 ####
#     4.                              "Minimum"  0.229699 ##
#     5.                 "LowGrayLevelEmphasis"  0.222965 #
#     6.              "LargeDependenceEmphasis"  0.221946 #
#     7. "LargeDependenceHighGrayLevelEmphasis"  0.218720 #
#     8.               "GrayLevelNonUniformity"  0.211368
#     9.                    "GrayLevelVariance"  0.206270
#    10.  "SmallDependenceLowGrayLevelEmphasis"  0.204852
#    11.              "SmallDependenceEmphasis"  0.204232
#    12.                         "90Percentile"  0.202829
#    13. "SmallDependenceHighGrayLevelEmphasis"  0.202456
#    14.                    "DependenceEntropy"  0.200868
#    15.                "MeanAbsoluteDeviation"  0.200650
#    16.              "DependenceNonUniformity"  0.199807
#    17.                               "Energy"  0.199715
#    18.                      "RootMeanSquared"  0.199661
#    19.    "DependenceNonUniformityNormalized"  0.199532
#    20.                                 "Mean"  0.199511
#    21.                              "Maximum"  0.199403
#    22.                          "TotalEnergy"  0.199388
#    23.                             "Variance"  0.199227
#    24.                           "Uniformity"  0.199042
#    25.                              "Entropy"  0.199028
#    26.                               "Median"  0.198999
#    27.          "RobustMeanAbsoluteDeviation"  0.198938
#    28.                             "Skewness"  0.198885
#    29.                                "Range"  0.198732
#    30.                             "Kurtosis"  0.198709
#    31.                         "10Percentile"  0.198678
#    32.                   "InterquartileRange"  0.198641
#
# Variable Importance: NUM_AS_ROOT:
#     1.  "LargeDependenceLowGrayLevelEmphasis" 171.000000 ################
#     2.                   "DependenceVariance" 94.000000 ########
#     3. "LargeDependenceHighGrayLevelEmphasis" 24.000000 #
#     4.               "GrayLevelNonUniformity" 10.000000
#
# Variable Importance: NUM_NODES:
#     1.  "LargeDependenceLowGrayLevelEmphasis" 646.000000 ################
#     2.                   "DependenceVariance" 591.000000 ##############
#     3.                "HighGrayLevelEmphasis" 478.000000 ###########
#     4.              "LargeDependenceEmphasis" 332.000000 ########
#     5. "LargeDependenceHighGrayLevelEmphasis" 267.000000 ######
#     6.               "GrayLevelNonUniformity" 248.000000 ######
#     7.                 "LowGrayLevelEmphasis" 246.000000 ######
#     8. "SmallDependenceHighGrayLevelEmphasis" 226.000000 #####
#     9.                              "Minimum" 223.000000 #####
#    10.                    "GrayLevelVariance" 180.000000 ####
#    11.              "SmallDependenceEmphasis" 157.000000 ###
#    12.                "MeanAbsoluteDeviation" 114.000000 ##
#    13.                         "90Percentile" 99.000000 ##
#    14.                    "DependenceEntropy" 82.000000 #
#    15.                      "RootMeanSquared" 68.000000 #
#    16.                                 "Mean" 62.000000 #
#    17.                               "Energy" 61.000000 #
#    18.                          "TotalEnergy" 61.000000 #
#    19.  "SmallDependenceLowGrayLevelEmphasis" 55.000000 #
#    20.                             "Variance" 43.000000
#    21.    "DependenceNonUniformityNormalized" 36.000000
#    22.              "DependenceNonUniformity" 35.000000
#    23.                              "Entropy" 27.000000
#    24.                              "Maximum" 12.000000
#    25.          "RobustMeanAbsoluteDeviation" 10.000000
#    26.                           "Uniformity" 10.000000
#    27.                               "Median"  9.000000
#    28.                             "Skewness"  9.000000
#    29.                         "10Percentile"  8.000000
#    30.                             "Kurtosis"  8.000000
#    31.                                "Range"  7.000000
#    32.                   "InterquartileRange"  4.000000
#
# Variable Importance: SUM_SCORE:
#     1.  "LargeDependenceLowGrayLevelEmphasis" 656.751922 ################
#     2.                 "LowGrayLevelEmphasis" 175.022348 ####
#     3.                   "DependenceVariance" 72.348992 #
#     4.  "SmallDependenceLowGrayLevelEmphasis" 48.409682 #
#     5.               "GrayLevelNonUniformity"  0.000009
#     6. "LargeDependenceHighGrayLevelEmphasis"  0.000003
#     7.                "HighGrayLevelEmphasis"  0.000001
#     8.                              "Minimum"  0.000001
#     9.                         "90Percentile"  0.000000
#    10.              "LargeDependenceEmphasis"  0.000000
#    11.                "MeanAbsoluteDeviation"  0.000000
#    12. "SmallDependenceHighGrayLevelEmphasis"  0.000000
#    13.                    "DependenceEntropy"  0.000000
#    14.                             "Variance"  0.000000
#    15.                      "RootMeanSquared"  0.000000
#    16.                                 "Mean"  0.000000
#    17.                               "Energy"  0.000000
#    18.                    "GrayLevelVariance"  0.000000
#    19.                          "TotalEnergy"  0.000000
#    20.                              "Entropy"  0.000000
#    21.              "SmallDependenceEmphasis"  0.000000
#    22.                              "Maximum"  0.000000
#    23.              "DependenceNonUniformity"  0.000000
#    24.    "DependenceNonUniformityNormalized"  0.000000
#    25.                             "Skewness"  0.000000
#    26.                             "Kurtosis"  0.000000
#    27.                   "InterquartileRange"  0.000000
#    28.                               "Median"  0.000000
#    29.                                "Range"  0.000000
#    30.                         "10Percentile"  0.000000
#    31.                           "Uniformity"  0.000000
#    32.          "RobustMeanAbsoluteDeviation"  0.000000
#
#
#
# Loss: BINOMIAL_LOG_LIKELIHOOD
# Validation loss value: 2.78764e-06
# Number of trees per iteration: 1
# Node format: NOT_SET
# Number of trees: 299
# Total number of nodes: 9127
#
# Number of nodes by tree:
# Count: 299 Average: 30.5251 StdDev: 11.1386
# Min: 9 Max: 45 Ignored: 0
# ----------------------------------------------
# [  9, 10)   3   1.00%   1.00%
# [ 10, 12)  15   5.02%   6.02% #
# [ 12, 14)  30  10.03%  16.05% ###
# [ 14, 16)  25   8.36%  24.41% ##
# [ 16, 18)   8   2.68%  27.09% #
# [ 18, 20)   2   0.67%  27.76%
# [ 20, 21)   0   0.00%  27.76%
# [ 21, 23)   3   1.00%  28.76%
# [ 23, 25)   0   0.00%  28.76%
# [ 25, 27)   0   0.00%  28.76%
# [ 27, 29)   1   0.33%  29.10%
# [ 29, 31)   0   0.00%  29.10%
# [ 31, 33)   1   0.33%  29.43%
# [ 33, 34)  25   8.36%  37.79% ##
# [ 34, 36) 107  35.79%  73.58% ##########
# [ 36, 38)   1   0.33%  73.91%
# [ 38, 40)  16   5.35%  79.26% #
# [ 40, 42)  24   8.03%  87.29% ##
# [ 42, 44)  25   8.36%  95.65% ##
# [ 44, 45]  13   4.35% 100.00% #
#
# Depth by leafs:
# Count: 4713 Average: 4.26735 StdDev: 0.852493
# Min: 1 Max: 5 Ignored: 0
# ----------------------------------------------
# [ 1, 2)    3   0.06%   0.06%
# [ 2, 3)  136   2.89%   2.95% #
# [ 3, 4)  825  17.50%  20.45% ###
# [ 4, 5) 1383  29.34%  49.80% ######
# [ 5, 5] 2366  50.20% 100.00% ##########
#
# Number of training obs by leaf:
# Count: 4713 Average: 44.9801 StdDev: 92.7938
# Min: 5 Max: 558 Ignored: 0
# ----------------------------------------------
# [   5,  32) 3870  82.11%  82.11% ##########
# [  32,  60)  112   2.38%  84.49%
# [  60,  88)   96   2.04%  86.53%
# [  88, 115)   47   1.00%  87.52%
# [ 115, 143)   51   1.08%  88.61%
# [ 143, 171)    4   0.08%  88.69%
# [ 171, 198)   11   0.23%  88.92%
# [ 198, 226)   71   1.51%  90.43%
# [ 226, 254)  155   3.29%  93.72%
# [ 254, 282)   29   0.62%  94.33%
# [ 282, 309)   91   1.93%  96.27%
# [ 309, 337)   25   0.53%  96.80%
# [ 337, 365)  128   2.72%  99.51%
# [ 365, 392)    0   0.00%  99.51%
# [ 392, 420)    0   0.00%  99.51%
# [ 420, 448)    0   0.00%  99.51%
# [ 448, 475)    0   0.00%  99.51%
# [ 475, 503)    0   0.00%  99.51%
# [ 503, 531)    0   0.00%  99.51%
# [ 531, 558]   23   0.49% 100.00%
#
# Attribute in nodes:
# 	646 : LargeDependenceLowGrayLevelEmphasis [NUMERICAL]
# 	591 : DependenceVariance [NUMERICAL]
# 	478 : HighGrayLevelEmphasis [NUMERICAL]
# 	332 : LargeDependenceEmphasis [NUMERICAL]
# 	267 : LargeDependenceHighGrayLevelEmphasis [NUMERICAL]
# 	248 : GrayLevelNonUniformity [NUMERICAL]
# 	246 : LowGrayLevelEmphasis [NUMERICAL]
# 	226 : SmallDependenceHighGrayLevelEmphasis [NUMERICAL]
# 	223 : Minimum [NUMERICAL]
# 	180 : GrayLevelVariance [NUMERICAL]
# 	157 : SmallDependenceEmphasis [NUMERICAL]
# 	114 : MeanAbsoluteDeviation [NUMERICAL]
# 	99 : 90Percentile [NUMERICAL]
# 	82 : DependenceEntropy [NUMERICAL]
# 	68 : RootMeanSquared [NUMERICAL]
# 	62 : Mean [NUMERICAL]
# 	61 : TotalEnergy [NUMERICAL]
# 	61 : Energy [NUMERICAL]
# 	55 : SmallDependenceLowGrayLevelEmphasis [NUMERICAL]
# 	43 : Variance [NUMERICAL]
# 	36 : DependenceNonUniformityNormalized [NUMERICAL]
# 	35 : DependenceNonUniformity [NUMERICAL]
# 	27 : Entropy [NUMERICAL]
# 	12 : Maximum [NUMERICAL]
# 	10 : Uniformity [NUMERICAL]
# 	10 : RobustMeanAbsoluteDeviation [NUMERICAL]
# 	9 : Skewness [NUMERICAL]
# 	9 : Median [NUMERICAL]
# 	8 : Kurtosis [NUMERICAL]
# 	8 : 10Percentile [NUMERICAL]
# 	7 : Range [NUMERICAL]
# 	4 : InterquartileRange [NUMERICAL]
#
# Attribute in nodes with depth <= 0:
# 	171 : LargeDependenceLowGrayLevelEmphasis [NUMERICAL]
# 	94 : DependenceVariance [NUMERICAL]
# 	24 : LargeDependenceHighGrayLevelEmphasis [NUMERICAL]
# 	10 : GrayLevelNonUniformity [NUMERICAL]
#
# Attribute in nodes with depth <= 1:
# 	311 : LargeDependenceLowGrayLevelEmphasis [NUMERICAL]
# 	164 : DependenceVariance [NUMERICAL]
# 	100 : Minimum [NUMERICAL]
# 	73 : LowGrayLevelEmphasis [NUMERICAL]
# 	61 : HighGrayLevelEmphasis [NUMERICAL]
# 	54 : LargeDependenceHighGrayLevelEmphasis [NUMERICAL]
# 	37 : LargeDependenceEmphasis [NUMERICAL]
# 	31 : SmallDependenceLowGrayLevelEmphasis [NUMERICAL]
# 	27 : GrayLevelNonUniformity [NUMERICAL]
# 	12 : GrayLevelVariance [NUMERICAL]
# 	9 : DependenceNonUniformity [NUMERICAL]
# 	6 : DependenceEntropy [NUMERICAL]
# 	4 : DependenceNonUniformityNormalized [NUMERICAL]
# 	3 : SmallDependenceHighGrayLevelEmphasis [NUMERICAL]
# 	2 : SmallDependenceEmphasis [NUMERICAL]
#
# Attribute in nodes with depth <= 2:
# 	397 : LargeDependenceLowGrayLevelEmphasis [NUMERICAL]
# 	370 : HighGrayLevelEmphasis [NUMERICAL]
# 	275 : DependenceVariance [NUMERICAL]
# 	219 : Minimum [NUMERICAL]
# 	152 : LargeDependenceEmphasis [NUMERICAL]
# 	95 : LowGrayLevelEmphasis [NUMERICAL]
# 	60 : LargeDependenceHighGrayLevelEmphasis [NUMERICAL]
# 	50 : GrayLevelNonUniformity [NUMERICAL]
# 	41 : SmallDependenceLowGrayLevelEmphasis [NUMERICAL]
# 	33 : RootMeanSquared [NUMERICAL]
# 	32 : Energy [NUMERICAL]
# 	31 : TotalEnergy [NUMERICAL]
# 	30 : GrayLevelVariance [NUMERICAL]
# 	21 : Mean [NUMERICAL]
# 	18 : DependenceNonUniformity [NUMERICAL]
# 	18 : DependenceEntropy [NUMERICAL]
# 	16 : SmallDependenceHighGrayLevelEmphasis [NUMERICAL]
# 	16 : SmallDependenceEmphasis [NUMERICAL]
# 	13 : DependenceNonUniformityNormalized [NUMERICAL]
# 	8 : Median [NUMERICAL]
# 	8 : Maximum [NUMERICAL]
# 	7 : MeanAbsoluteDeviation [NUMERICAL]
# 	5 : Variance [NUMERICAL]
# 	5 : Uniformity [NUMERICAL]
# 	5 : Skewness [NUMERICAL]
# 	5 : Entropy [NUMERICAL]
# 	5 : 10Percentile [NUMERICAL]
# 	4 : RobustMeanAbsoluteDeviation [NUMERICAL]
# 	3 : Range [NUMERICAL]
# 	3 : InterquartileRange [NUMERICAL]
# 	2 : Kurtosis [NUMERICAL]
# 	1 : 90Percentile [NUMERICAL]
#
# Attribute in nodes with depth <= 3:
# 	505 : DependenceVariance [NUMERICAL]
# 	497 : LargeDependenceLowGrayLevelEmphasis [NUMERICAL]
# 	461 : HighGrayLevelEmphasis [NUMERICAL]
# 	257 : LargeDependenceEmphasis [NUMERICAL]
# 	222 : Minimum [NUMERICAL]
# 	187 : LowGrayLevelEmphasis [NUMERICAL]
# 	168 : GrayLevelNonUniformity [NUMERICAL]
# 	150 : GrayLevelVariance [NUMERICAL]
# 	99 : SmallDependenceEmphasis [NUMERICAL]
# 	79 : 90Percentile [NUMERICAL]
# 	66 : RootMeanSquared [NUMERICAL]
# 	64 : LargeDependenceHighGrayLevelEmphasis [NUMERICAL]
# 	60 : TotalEnergy [NUMERICAL]
# 	59 : Mean [NUMERICAL]
# 	58 : Energy [NUMERICAL]
# 	51 : SmallDependenceLowGrayLevelEmphasis [NUMERICAL]
# 	46 : SmallDependenceHighGrayLevelEmphasis [NUMERICAL]
# 	43 : DependenceEntropy [NUMERICAL]
# 	32 : DependenceNonUniformityNormalized [NUMERICAL]
# 	29 : DependenceNonUniformity [NUMERICAL]
# 	14 : MeanAbsoluteDeviation [NUMERICAL]
# 	11 : Maximum [NUMERICAL]
# 	9 : Skewness [NUMERICAL]
# 	9 : RobustMeanAbsoluteDeviation [NUMERICAL]
# 	9 : Median [NUMERICAL]
# 	8 : Uniformity [NUMERICAL]
# 	8 : Kurtosis [NUMERICAL]
# 	7 : Range [NUMERICAL]
# 	7 : Entropy [NUMERICAL]
# 	6 : Variance [NUMERICAL]
# 	6 : 10Percentile [NUMERICAL]
# 	4 : InterquartileRange [NUMERICAL]
#
# Attribute in nodes with depth <= 5:
# 	646 : LargeDependenceLowGrayLevelEmphasis [NUMERICAL]
# 	591 : DependenceVariance [NUMERICAL]
# 	478 : HighGrayLevelEmphasis [NUMERICAL]
# 	332 : LargeDependenceEmphasis [NUMERICAL]
# 	267 : LargeDependenceHighGrayLevelEmphasis [NUMERICAL]
# 	248 : GrayLevelNonUniformity [NUMERICAL]
# 	246 : LowGrayLevelEmphasis [NUMERICAL]
# 	226 : SmallDependenceHighGrayLevelEmphasis [NUMERICAL]
# 	223 : Minimum [NUMERICAL]
# 	180 : GrayLevelVariance [NUMERICAL]
# 	157 : SmallDependenceEmphasis [NUMERICAL]
# 	114 : MeanAbsoluteDeviation [NUMERICAL]
# 	99 : 90Percentile [NUMERICAL]
# 	82 : DependenceEntropy [NUMERICAL]
# 	68 : RootMeanSquared [NUMERICAL]
# 	62 : Mean [NUMERICAL]
# 	61 : TotalEnergy [NUMERICAL]
# 	61 : Energy [NUMERICAL]
# 	55 : SmallDependenceLowGrayLevelEmphasis [NUMERICAL]
# 	43 : Variance [NUMERICAL]
# 	36 : DependenceNonUniformityNormalized [NUMERICAL]
# 	35 : DependenceNonUniformity [NUMERICAL]
# 	27 : Entropy [NUMERICAL]
# 	12 : Maximum [NUMERICAL]
# 	10 : Uniformity [NUMERICAL]
# 	10 : RobustMeanAbsoluteDeviation [NUMERICAL]
# 	9 : Skewness [NUMERICAL]
# 	9 : Median [NUMERICAL]
# 	8 : Kurtosis [NUMERICAL]
# 	8 : 10Percentile [NUMERICAL]
# 	7 : Range [NUMERICAL]
# 	4 : InterquartileRange [NUMERICAL]
#
# Condition type in nodes:
# 	4414 : HigherCondition
# Condition type in nodes with depth <= 0:
# 	299 : HigherCondition
# Condition type in nodes with depth <= 1:
# 	894 : HigherCondition
# Condition type in nodes with depth <= 2:
# 	1948 : HigherCondition
# Condition type in nodes with depth <= 3:
# 	3231 : HigherCondition
# Condition type in nodes with depth <= 5:
# 	4414 : HigherCondition
#
# Training logs:
# Number of iteration to final model: 299
# 	Iter:1 train-loss:1.195807 valid-loss:1.204546  train-accuracy:1.000000 valid-accuracy:1.000000
# 	Iter:2 train-loss:1.040216 valid-loss:1.047446  train-accuracy:1.000000 valid-accuracy:1.000000
# 	Iter:3 train-loss:0.910484 valid-loss:0.916559  train-accuracy:1.000000 valid-accuracy:1.000000
# 	Iter:4 train-loss:0.800830 valid-loss:0.805995  train-accuracy:1.000000 valid-accuracy:1.000000
# 	Iter:5 train-loss:0.707164 valid-loss:0.711597  train-accuracy:1.000000 valid-accuracy:1.000000
# 	Iter:6 train-loss:0.626480 valid-loss:0.630312  train-accuracy:1.000000 valid-accuracy:1.000000
# 	Iter:16 train-loss:0.205984 valid-loss:0.207099  train-accuracy:1.000000 valid-accuracy:1.000000
# 	Iter:26 train-loss:0.073080 valid-loss:0.073461  train-accuracy:1.000000 valid-accuracy:1.000000
# 	Iter:36 train-loss:0.026544 valid-loss:0.026680  train-accuracy:1.000000 valid-accuracy:1.000000
# 	Iter:46 train-loss:0.009720 valid-loss:0.009769  train-accuracy:1.000000 valid-accuracy:1.000000
# 	Iter:56 train-loss:0.003570 valid-loss:0.003588  train-accuracy:1.000000 valid-accuracy:1.000000
# 	Iter:66 train-loss:0.001312 valid-loss:0.001319  train-accuracy:1.000000 valid-accuracy:1.000000
# 	Iter:76 train-loss:0.000483 valid-loss:0.000485  train-accuracy:1.000000 valid-accuracy:1.000000
# 	Iter:86 train-loss:0.000178 valid-loss:0.000179  train-accuracy:1.000000 valid-accuracy:1.000000
# 	Iter:96 train-loss:0.000072 valid-loss:0.000073  train-accuracy:1.000000 valid-accuracy:1.000000
# 	Iter:106 train-loss:0.000033 valid-loss:0.000034  train-accuracy:1.000000 valid-accuracy:1.000000
# 	Iter:116 train-loss:0.000019 valid-loss:0.000020  train-accuracy:1.000000 valid-accuracy:1.000000
# 	Iter:126 train-loss:0.000013 valid-loss:0.000014  train-accuracy:1.000000 valid-accuracy:1.000000
# 	Iter:136 train-loss:0.000010 valid-loss:0.000011  train-accuracy:1.000000 valid-accuracy:1.000000
# 	Iter:146 train-loss:0.000008 valid-loss:0.000009  train-accuracy:1.000000 valid-accuracy:1.000000
# 	Iter:156 train-loss:0.000007 valid-loss:0.000008  train-accuracy:1.000000 valid-accuracy:1.000000
# 	Iter:166 train-loss:0.000007 valid-loss:0.000007  train-accuracy:1.000000 valid-accuracy:1.000000
# 	Iter:176 train-loss:0.000006 valid-loss:0.000007  train-accuracy:1.000000 valid-accuracy:1.000000
# 	Iter:186 train-loss:0.000006 valid-loss:0.000006  train-accuracy:1.000000 valid-accuracy:1.000000
# 	Iter:196 train-loss:0.000005 valid-loss:0.000006  train-accuracy:1.000000 valid-accuracy:1.000000
# 	Iter:206 train-loss:0.000004 valid-loss:0.000005  train-accuracy:1.000000 valid-accuracy:1.000000
# 	Iter:216 train-loss:0.000003 valid-loss:0.000004  train-accuracy:1.000000 valid-accuracy:1.000000
# 	Iter:226 train-loss:0.000003 valid-loss:0.000004  train-accuracy:1.000000 valid-accuracy:1.000000
# 	Iter:236 train-loss:0.000003 valid-loss:0.000004  train-accuracy:1.000000 valid-accuracy:1.000000
# 	Iter:246 train-loss:0.000003 valid-loss:0.000004  train-accuracy:1.000000 valid-accuracy:1.000000
# 	Iter:256 train-loss:0.000003 valid-loss:0.000003  train-accuracy:1.000000 valid-accuracy:1.000000
# 	Iter:266 train-loss:0.000002 valid-loss:0.000003  train-accuracy:1.000000 valid-accuracy:1.000000
# 	Iter:276 train-loss:0.000002 valid-loss:0.000003  train-accuracy:1.000000 valid-accuracy:1.000000
# 	Iter:286 train-loss:0.000002 valid-loss:0.000003  train-accuracy:1.000000 valid-accuracy:1.000000
# 	Iter:296 train-loss:0.000002 valid-loss:0.000003  train-accuracy:1.000000 valid-accuracy:1.000000

# %%
# Model features
model.make_inspector().features()
# Out:
# ["10Percentile" (1; #0),
#  "90Percentile" (1; #1),
#  "DependenceEntropy" (1; #2),
#  "DependenceNonUniformity" (1; #3),
#  "DependenceNonUniformityNormalized" (1; #4),
#  "DependenceVariance" (1; #5),
#  "Energy" (1; #6),
#  "Entropy" (1; #7),
#  "GrayLevelNonUniformity" (1; #8),
#  "GrayLevelVariance" (1; #9),
#  "HighGrayLevelEmphasis" (1; #10),
#  "InterquartileRange" (1; #11),
#  "Kurtosis" (1; #12),
#  "LargeDependenceEmphasis" (1; #13),
#  "LargeDependenceHighGrayLevelEmphasis" (1; #14),
#  "LargeDependenceLowGrayLevelEmphasis" (1; #15),
#  "LowGrayLevelEmphasis" (1; #16),
#  "Maximum" (1; #17),
#  "Mean" (1; #18),
#  "MeanAbsoluteDeviation" (1; #19),
#  "Median" (1; #20),
#  "Minimum" (1; #21),
#  "Range" (1; #22),
#  "RobustMeanAbsoluteDeviation" (1; #23),
#  "RootMeanSquared" (1; #24),
#  "Skewness" (1; #25),
#  "SmallDependenceEmphasis" (1; #26),
#  "SmallDependenceHighGrayLevelEmphasis" (1; #27),
#  "SmallDependenceLowGrayLevelEmphasis" (1; #28),
#  "TotalEnergy" (1; #29),
#  "Uniformity" (1; #30),
#  "Variance" (1; #31)]

# %%
# Feature importance
model.make_inspector().variable_importances()
# Out:
# {'INV_MEAN_MIN_DEPTH': [("LargeDependenceLowGrayLevelEmphasis" (1; #15),
#    0.41605062515420466),
#   ("DependenceVariance" (1; #5), 0.31870585128040463),
#   ("HighGrayLevelEmphasis" (1; #10), 0.25461137512505827),
#   ("Minimum" (1; #21), 0.22969947628420487),
#   ("LowGrayLevelEmphasis" (1; #16), 0.22296522128346757),
#   ("LargeDependenceEmphasis" (1; #13), 0.22194558458837288),
#   ("LargeDependenceHighGrayLevelEmphasis" (1; #14), 0.218720204123446),
#   ("GrayLevelNonUniformity" (1; #8), 0.21136764959385498),
#   ("GrayLevelVariance" (1; #9), 0.20626981308204917),
#   ("SmallDependenceLowGrayLevelEmphasis" (1; #28), 0.20485151840854676),
#   ("SmallDependenceEmphasis" (1; #26), 0.204232053811522),
#   ("90Percentile" (1; #1), 0.20282850311556025),
#   ("SmallDependenceHighGrayLevelEmphasis" (1; #27), 0.2024563997354491),
#   ("DependenceEntropy" (1; #2), 0.2008682458056439),
#   ("MeanAbsoluteDeviation" (1; #19), 0.20065005481830483),
#   ("DependenceNonUniformity" (1; #3), 0.1998071153612704),
#   ("Energy" (1; #6), 0.19971467689877223),
#   ("RootMeanSquared" (1; #24), 0.19966072050164618),
#   ("DependenceNonUniformityNormalized" (1; #4), 0.19953168545846475),
#   ("Mean" (1; #18), 0.19951090579017502),
#   ("Maximum" (1; #17), 0.19940339114103858),
#   ("TotalEnergy" (1; #29), 0.19938775097996647),
#   ("Variance" (1; #31), 0.19922650868504757),
#   ("Uniformity" (1; #30), 0.19904191747585553),
#   ("Entropy" (1; #7), 0.19902802932264238),
#   ("Median" (1; #20), 0.1989987207526541),
#   ("RobustMeanAbsoluteDeviation" (1; #23), 0.1989380738676568),
#   ("Skewness" (1; #25), 0.1988850003243896),
#   ("Range" (1; #22), 0.19873229964660208),
#   ("Kurtosis" (1; #12), 0.1987090295974022),
#   ("10Percentile" (1; #0), 0.19867822089112264),
#   ("InterquartileRange" (1; #11), 0.1986409278961935)],
#  'SUM_SCORE': [("LargeDependenceLowGrayLevelEmphasis" (1; #15),
#    656.7519216808108),
#   ("LowGrayLevelEmphasis" (1; #16), 175.02234752760754),
#   ("DependenceVariance" (1; #5), 72.34899221491185),
#   ("SmallDependenceLowGrayLevelEmphasis" (1; #28), 48.409682329129005),
#   ("GrayLevelNonUniformity" (1; #8), 9.44568426587038e-06),
#   ("LargeDependenceHighGrayLevelEmphasis" (1; #14), 2.807441312017616e-06),
#   ("HighGrayLevelEmphasis" (1; #10), 7.779718832297553e-07),
#   ("Minimum" (1; #21), 5.883055684689066e-07),
#   ("90Percentile" (1; #1), 1.8946907253238618e-07),
#   ("LargeDependenceEmphasis" (1; #13), 1.2309274090557914e-07),
#   ("MeanAbsoluteDeviation" (1; #19), 8.878940942100186e-08),
#   ("SmallDependenceHighGrayLevelEmphasis" (1; #27), 1.8391457417249236e-08),
#   ("DependenceEntropy" (1; #2), 1.789823444421849e-08),
#   ("Variance" (1; #31), 1.7582888309720056e-08),
#   ("RootMeanSquared" (1; #24), 1.4973505516160838e-08),
#   ("Mean" (1; #18), 1.2619581051425913e-08),
#   ("Energy" (1; #6), 1.2363861264877687e-08),
#   ("GrayLevelVariance" (1; #9), 1.1976725549067297e-08),
#   ("TotalEnergy" (1; #29), 1.1946430066551574e-08),
#   ("Entropy" (1; #7), 1.0336513984076418e-08),
#   ("SmallDependenceEmphasis" (1; #26), 4.039237336497423e-09),
#   ("Maximum" (1; #17), 1.9745609287343256e-09),
#   ("DependenceNonUniformity" (1; #3), 5.45247601182482e-10),
#   ("DependenceNonUniformityNormalized" (1; #4), 3.3943580467055774e-10),
#   ("Skewness" (1; #25), 1.2298485482484013e-14),
#   ("Kurtosis" (1; #12), 5.585909005194616e-15),
#   ("InterquartileRange" (1; #11), 5.38458154049657e-15),
#   ("Median" (1; #20), 4.204756451788882e-15),
#   ("Range" (1; #22), 2.1757786344387036e-15),
#   ("10Percentile" (1; #0), 1.125128928305105e-15),
#   ("Uniformity" (1; #30), 4.807712593822632e-16),
#   ("RobustMeanAbsoluteDeviation" (1; #23), 4.002350687100629e-16)],
#  'NUM_AS_ROOT': [("LargeDependenceLowGrayLevelEmphasis" (1; #15), 171.0),
#   ("DependenceVariance" (1; #5), 94.0),
#   ("LargeDependenceHighGrayLevelEmphasis" (1; #14), 24.0),
#   ("GrayLevelNonUniformity" (1; #8), 10.0)],
#  'NUM_NODES': [("LargeDependenceLowGrayLevelEmphasis" (1; #15), 646.0),
#   ("DependenceVariance" (1; #5), 591.0),
#   ("HighGrayLevelEmphasis" (1; #10), 478.0),
#   ("LargeDependenceEmphasis" (1; #13), 332.0),
#   ("LargeDependenceHighGrayLevelEmphasis" (1; #14), 267.0),
#   ("GrayLevelNonUniformity" (1; #8), 248.0),
#   ("LowGrayLevelEmphasis" (1; #16), 246.0),
#   ("SmallDependenceHighGrayLevelEmphasis" (1; #27), 226.0),
#   ("Minimum" (1; #21), 223.0),
#   ("GrayLevelVariance" (1; #9), 180.0),
#   ("SmallDependenceEmphasis" (1; #26), 157.0),
#   ("MeanAbsoluteDeviation" (1; #19), 114.0),
#   ("90Percentile" (1; #1), 99.0),
#   ("DependenceEntropy" (1; #2), 82.0),
#   ("RootMeanSquared" (1; #24), 68.0),
#   ("Mean" (1; #18), 62.0),
#   ("Energy" (1; #6), 61.0),
#   ("TotalEnergy" (1; #29), 61.0),
#   ("SmallDependenceLowGrayLevelEmphasis" (1; #28), 55.0),
#   ("Variance" (1; #31), 43.0),
#   ("DependenceNonUniformityNormalized" (1; #4), 36.0),
#   ("DependenceNonUniformity" (1; #3), 35.0),
#   ("Entropy" (1; #7), 27.0),
#   ("Maximum" (1; #17), 12.0),
#   ("RobustMeanAbsoluteDeviation" (1; #23), 10.0),
#   ("Uniformity" (1; #30), 10.0),
#   ("Median" (1; #20), 9.0),
#   ("Skewness" (1; #25), 9.0),
#   ("10Percentile" (1; #0), 8.0),
#   ("Kurtosis" (1; #12), 8.0),
#   ("Range" (1; #22), 7.0),
#   ("InterquartileRange" (1; #11), 4.0)]}

# %%
# Model self evaluation
model.make_inspector().evaluation()
# Out:
# Evaluation(num_examples=None, accuracy=1.0, loss=2.7876424155692803e-06, rmse=None, ndcg=None, aucs=None, auuc=None, qini=None)

# %%
logs = model.make_inspector().training_logs()

plt.figure(figsize=(12, 4))
plt.subplot(1, 2, 1)
plt.plot([log.num_trees for log in logs], [log.evaluation.accuracy for log in logs])
plt.xlabel("Number of trees")
plt.ylabel("Accuracy (out-of-bag)")
plt.subplot(1, 2, 2)
plt.plot([log.num_trees for log in logs], [log.evaluation.loss for log in logs])
plt.xlabel("Number of trees")
plt.ylabel("Logloss (out-of-bag)")
plt.show()

# %% [markdown]
# Calculate the score of our hold-out validation dataset

# %%
predictions = model.predict(val_ds)
y_true      = validation_data["label"]

from sklearn.metrics import roc_auc_score
ROC_AUC = roc_auc_score(y_true, predictions)
print("The ROC AUC score is %.5f" % ROC_AUC )
# Out:
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 74ms/step
# The ROC AUC score is 1.00000

# %%
# Compute binary classification metrics with sklearn
import numpy as np
from sklearn.metrics import (
    accuracy_score,
    precision_score,
    recall_score,
    f1_score,
    roc_auc_score,
    average_precision_score,
    confusion_matrix,
    classification_report,
    matthews_corrcoef,
    log_loss,
    brier_score_loss,
)

# Get predictions (probabilities or class labels)
preds = model.predict(test_ds)
# If model outputs probabilities, convert to labels by threshold 0.5
if preds.ndim == 2:
    # For TFDF classification, preds may be class probabilities with shape (N, 2)
    if preds.shape[1] == 2:
        pos_probs = preds[:, 1]
    else:
        # If single-probability column (positive class)
        pos_probs = preds[:, -1]
    y_pred = (pos_probs >= 0.5).astype(int)
else:
    # Already class labels
    y_pred = preds.astype(int)
    pos_probs = None

# Ground truth labels (must be 0/1 integers)
y_true = test_data["label"].astype(int).to_numpy()

# Core metrics
metrics = {}
metrics["accuracy"] = accuracy_score(y_true, y_pred)
metrics["precision"] = precision_score(y_true, y_pred, zero_division=0)
metrics["recall"] = recall_score(y_true, y_pred, zero_division=0)
metrics["f1"] = f1_score(y_true, y_pred, zero_division=0)
metrics["mcc"] = matthews_corrcoef(y_true, y_pred)

# Probabilistic metrics (only if we have probabilities)
if pos_probs is not None:
    metrics["roc_auc"] = roc_auc_score(y_true, pos_probs)
    metrics["pr_auc"] = average_precision_score(y_true, pos_probs)
    metrics["log_loss"] = log_loss(y_true, pos_probs, labels=[0,1])
    metrics["brier_score"] = brier_score_loss(y_true, pos_probs)

# Confusion matrix and detailed report
cm = confusion_matrix(y_true, y_pred, labels=[0,1])
report = classification_report(y_true, y_pred, digits=4)

print("Sklearn binary metrics:")
for k, v in metrics.items():
    print(f"{k}: {v:.4f}")
print("\nConfusion matrix:\n", cm)
print("\nClassification report:\n", report)
# Out:
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 71ms/step
# Sklearn binary metrics:
# accuracy: 1.0000
# precision: 1.0000
# recall: 1.0000
# f1: 1.0000
# mcc: 1.0000
# roc_auc: 1.0000
# pr_auc: 1.0000
# log_loss: 0.0000
# brier_score: 0.0000
#
# Confusion matrix:
#  [[107   0]
#  [  0 115]]
#
# Classification report:
#                precision    recall  f1-score   support
#
#            0     1.0000    1.0000    1.0000       107
#            1     1.0000    1.0000    1.0000       115
#
#     accuracy                         1.0000       222
#    macro avg     1.0000    1.0000    1.0000       222
# weighted avg     1.0000    1.0000    1.0000       222
