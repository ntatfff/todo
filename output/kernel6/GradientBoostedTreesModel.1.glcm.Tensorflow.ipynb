# %%
# Import packages and modules
import numpy  as np
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow_decision_forests as tfdf

from sklearn.model_selection import train_test_split
# Out:
# 2026-08-15 05:05:58.302178: I tensorflow/core/util/port.cc:113] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2026-08-15 05:05:58.658282: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2026-08-15 05:06:03.478650: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
# Check the version of TensorFlow Decision Forests
print("Found TensorFlow Decision Forests v" + tfdf.__version__)
# Out:
# Found TensorFlow Decision Forests v1.9.1

# %%
datasetPath = 'dataset/firstorder/kernel5/dataset.csv'

# %%
# Parameters
datasetPath = "dataset/glcm/kernel6/1.dataset.csv"

# %%
# train/validation/test = 70/10/20
dataset = pd.read_csv(datasetPath)

train_data, temp_data = train_test_split(dataset, test_size=0.3, random_state=42)
validation_data, test_data = train_test_split(temp_data, test_size=2/3, random_state=42)

# %%
from sklearn.utils.class_weight import compute_class_weight

# tinh class weight tren tap train
classes = np.array([0, 1])
weights = compute_class_weight(class_weight="balanced", classes=classes, y=train_data["label"])
class_weight = {0: weights[0], 1: weights[1]}

# gan sample_weight cho tung dong
train_data["sample_weight"] = train_data["label"].map(class_weight)
validation_data["sample_weight"] = validation_data["label"].map(class_weight)
test_data["sample_weight"] = test_data["label"].map(class_weight)

# Convert the dataset into a TensorFlow dataset.
train_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    train_data, label="label", weight="sample_weight"
)         
val_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    validation_data, label="label", weight="sample_weight"
)
test_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    test_data, label="label", weight="sample_weight"
)
# Out:
# 2026-08-15 05:06:16.287094: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:984] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2026-08-15 05:06:16.288777: W tensorflow/core/common_runtime/gpu/gpu_device.cc:2251] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...

# %%
import keras

# %%
# %%time

# Train a Gradient Boosted Trees model.
model = tfdf.keras.GradientBoostedTreesModel()

# Add evaluation metrics
model.compile(
    metrics=["accuracy"]
)
model.fit(x=train_ds)

# # Train a Gradient Boosted Trees model.
# model = tfdf.keras.GradientBoostedTreesModel(num_trees=1500)
# model.fit(train_ds)
# Out:
# Use /tmp/tmpqs9d7xhy as temporary training directory
# Reading training dataset...
# [WARNING 26-08-15 05:06:16.4474 UTC gradient_boosted_trees.cc:1840] "goss_alpha" set but "sampling_method" not equal to "GOSS".
# [WARNING 26-08-15 05:06:16.4478 UTC gradient_boosted_trees.cc:1851] "goss_beta" set but "sampling_method" not equal to "GOSS".
# [WARNING 26-08-15 05:06:16.4478 UTC gradient_boosted_trees.cc:1865] "selective_gradient_boosting_ratio" set but "sampling_method" not equal to "SELGB".
# Training dataset read in 0:00:02.648512. Found 507 examples.
# Training model...
# Model trained in 0:00:00.632896
# Compiling model...
# [INFO 26-08-15 05:06:19.7564 UTC kernel.cc:1233] Loading model from path /tmp/tmpqs9d7xhy/model/ with prefix 33219bc61ee74a3b
# [INFO 26-08-15 05:06:19.7602 UTC quick_scorer_extended.cc:911] The binary was compiled without AVX2 support, but your CPU supports it. Enable it for faster model inference.
# [INFO 26-08-15 05:06:19.7604 UTC abstract_model.cc:1362] Engine "GradientBoostedTreesQuickScorerExtended" built
# [INFO 26-08-15 05:06:19.7604 UTC kernel.cc:1061] Use fast generic engine
# Model compiled.
# CPU times: user 6.02 s, sys: 887 ms, total: 6.91 s
# Wall time: 7.15 s

# %%
# Evaluate the model
evaluate = model.evaluate(val_ds, return_dict=True)
print()

for name, value in evaluate.items():
    print(f"{name}: {value:.4f}")
# Out:
# WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 1/1 [==============================] - ETA: 0s - loss: 0.0000e+00 - accuracy: 0.9722
# 1/1 [==============================] - 3s 3s/step - loss: 0.0000e+00 - accuracy: 0.9722
# loss: 0.0000
# accuracy: 0.9722

# %%
# Model Summary
model.summary()
# Out:
# Model: "gradient_boosted_trees_model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
# =================================================================
# Total params: 1 (1.00 Byte)
# Trainable params: 0 (0.00 Byte)
# Non-trainable params: 1 (1.00 Byte)
# _________________________________________________________________
# Type: "GRADIENT_BOOSTED_TREES"
# Task: CLASSIFICATION
# Label: "__LABEL"
#
# Input Features (24):
# 	Autocorrelation
# 	ClusterProminence
# 	ClusterShade
# 	ClusterTendency
# 	Contrast
# 	Correlation
# 	DifferenceAverage
# 	DifferenceEntropy
# 	DifferenceVariance
# 	Id
# 	Idm
# 	Idmn
# 	Idn
# 	Imc1
# 	Imc2
# 	InverseVariance
# 	JointAverage
# 	JointEnergy
# 	JointEntropy
# 	MCC
# 	MaximumProbability
# 	SumAverage
# 	SumEntropy
# 	SumSquares
#
# Trained with weights
#
# Variable Importance: INV_MEAN_MIN_DEPTH:
#     1.    "Autocorrelation"  0.381298 ################
#     2.         "SumAverage"  0.263307 #####
#     3.               "Imc2"  0.258704 ####
#     4.       "JointAverage"  0.245232 ###
#     5.       "ClusterShade"  0.241262 ###
#     6.        "Correlation"  0.240119 ###
#     7.       "JointEntropy"  0.228994 ##
#     8.                "MCC"  0.220909 #
#     9.                "Idn"  0.218971 #
#    10.         "SumEntropy"  0.213090
#    11.        "JointEnergy"  0.212328
#    12.               "Imc1"  0.212079
#    13. "MaximumProbability"  0.208942
#    14.  "ClusterProminence"  0.208593
#    15.    "InverseVariance"  0.208509
#    16.                "Idm"  0.206788
#    17.               "Idmn"  0.205578
#    18.           "Contrast"  0.205570
#    19.                 "Id"  0.205277
#    20. "DifferenceVariance"  0.204722
#    21.  "DifferenceEntropy"  0.203936
#    22.  "DifferenceAverage"  0.203763
#    23.         "SumSquares"  0.203697
#    24.    "ClusterTendency"  0.203646
#
# Variable Importance: NUM_AS_ROOT:
#     1. "Autocorrelation" 66.000000 ################
#     2.      "SumAverage" 32.000000 ###
#     3.    "JointAverage" 24.000000
#
# Variable Importance: NUM_NODES:
#     1.       "ClusterShade" 169.000000 ################
#     2.               "Imc2" 141.000000 #############
#     3.    "Autocorrelation" 138.000000 ############
#     4.         "SumAverage" 109.000000 ##########
#     5.       "JointEntropy" 107.000000 #########
#     6.       "JointAverage" 106.000000 #########
#     7.         "SumEntropy" 81.000000 #######
#     8.        "Correlation" 67.000000 #####
#     9.        "JointEnergy" 62.000000 #####
#    10.    "InverseVariance" 50.000000 ####
#    11.                "MCC" 45.000000 ###
#    12.                "Idm" 41.000000 ###
#    13.               "Imc1" 41.000000 ###
#    14. "MaximumProbability" 40.000000 ###
#    15.                "Idn" 36.000000 ##
#    16.  "ClusterProminence" 29.000000 ##
#    17.                 "Id" 28.000000 ##
#    18.           "Contrast" 18.000000 #
#    19. "DifferenceVariance" 16.000000
#    20.               "Idmn" 14.000000
#    21.  "DifferenceEntropy"  9.000000
#    22.         "SumSquares"  9.000000
#    23.  "DifferenceAverage"  8.000000
#    24.    "ClusterTendency"  7.000000
#
# Variable Importance: SUM_SCORE:
#     1.       "JointAverage" 222.686325 ################
#     2.         "SumAverage" 215.645433 ###############
#     3.               "Imc2" 128.759155 #########
#     4.                "MCC"  9.728121
#     5.               "Imc1"  5.694467
#     6.    "Autocorrelation"  3.937112
#     7.        "Correlation"  2.344516
#     8.       "JointEntropy"  0.966753
#     9.       "ClusterShade"  0.807643
#    10.                "Idm"  0.802736
#    11.         "SumEntropy"  0.618769
#    12.  "DifferenceEntropy"  0.426966
#    13. "MaximumProbability"  0.396613
#    14. "DifferenceVariance"  0.268210
#    15.        "JointEnergy"  0.167882
#    16.    "InverseVariance"  0.141479
#    17.           "Contrast"  0.074398
#    18.  "ClusterProminence"  0.061118
#    19.               "Idmn"  0.047293
#    20.                "Idn"  0.032867
#    21.                 "Id"  0.027298
#    22.    "ClusterTendency"  0.022258
#    23.         "SumSquares"  0.003343
#    24.  "DifferenceAverage"  0.002222
#
#
#
# Loss: BINOMIAL_LOG_LIKELIHOOD
# Validation loss value: 0.000103258
# Number of trees per iteration: 1
# Node format: NOT_SET
# Number of trees: 122
# Total number of nodes: 2864
#
# Number of nodes by tree:
# Count: 122 Average: 23.4754 StdDev: 6.05469
# Min: 13 Max: 37 Ignored: 0
# ----------------------------------------------
# [ 13, 14)  5   4.10%   4.10% #
# [ 14, 15)  0   0.00%   4.10%
# [ 15, 16)  6   4.92%   9.02% ##
# [ 16, 18) 11   9.02%  18.03% ###
# [ 18, 19)  0   0.00%  18.03%
# [ 19, 20) 14  11.48%  29.51% ####
# [ 20, 21)  0   0.00%  29.51%
# [ 21, 23) 21  17.21%  46.72% ######
# [ 23, 24)  5   4.10%  50.82% #
# [ 24, 25)  0   0.00%  50.82%
# [ 25, 26) 35  28.69%  79.51% ##########
# [ 26, 28)  5   4.10%  83.61% #
# [ 28, 29)  0   0.00%  83.61%
# [ 29, 30)  0   0.00%  83.61%
# [ 30, 31)  0   0.00%  83.61%
# [ 31, 33)  1   0.82%  84.43%
# [ 33, 34)  6   4.92%  89.34% ##
# [ 34, 35)  0   0.00%  89.34%
# [ 35, 36) 10   8.20%  97.54% ###
# [ 36, 37]  3   2.46% 100.00% #
#
# Depth by leafs:
# Count: 1493 Average: 4.00804 StdDev: 1.02934
# Min: 2 Max: 5 Ignored: 0
# ----------------------------------------------
# [ 2, 3) 145   9.71%   9.71% ##
# [ 3, 4) 350  23.44%  33.15% #####
# [ 4, 5) 346  23.17%  56.33% #####
# [ 5, 5] 652  43.67% 100.00% ##########
#
# Number of training obs by leaf:
# Count: 1493 Average: 37.4253 StdDev: 92.4496
# Min: 5 Max: 420 Ignored: 0
# ----------------------------------------------
# [   5,  25) 1258  84.26%  84.26% ##########
# [  25,  46)   61   4.09%  88.35%
# [  46,  67)   11   0.74%  89.08%
# [  67,  88)    6   0.40%  89.48%
# [  88, 109)    4   0.27%  89.75%
# [ 109, 129)   30   2.01%  91.76%
# [ 129, 150)    0   0.00%  91.76%
# [ 150, 171)    0   0.00%  91.76%
# [ 171, 192)    1   0.07%  91.83%
# [ 192, 213)    0   0.00%  91.83%
# [ 213, 233)    0   0.00%  91.83%
# [ 233, 254)   35   2.34%  94.17%
# [ 254, 275)    0   0.00%  94.17%
# [ 275, 296)    0   0.00%  94.17%
# [ 296, 317)    2   0.13%  94.31%
# [ 317, 337)   20   1.34%  95.65%
# [ 337, 358)   10   0.67%  96.32%
# [ 358, 379)   13   0.87%  97.19%
# [ 379, 400)   21   1.41%  98.59%
# [ 400, 420]   21   1.41% 100.00%
#
# Attribute in nodes:
# 	169 : ClusterShade [NUMERICAL]
# 	141 : Imc2 [NUMERICAL]
# 	138 : Autocorrelation [NUMERICAL]
# 	109 : SumAverage [NUMERICAL]
# 	107 : JointEntropy [NUMERICAL]
# 	106 : JointAverage [NUMERICAL]
# 	81 : SumEntropy [NUMERICAL]
# 	67 : Correlation [NUMERICAL]
# 	62 : JointEnergy [NUMERICAL]
# 	50 : InverseVariance [NUMERICAL]
# 	45 : MCC [NUMERICAL]
# 	41 : Imc1 [NUMERICAL]
# 	41 : Idm [NUMERICAL]
# 	40 : MaximumProbability [NUMERICAL]
# 	36 : Idn [NUMERICAL]
# 	29 : ClusterProminence [NUMERICAL]
# 	28 : Id [NUMERICAL]
# 	18 : Contrast [NUMERICAL]
# 	16 : DifferenceVariance [NUMERICAL]
# 	14 : Idmn [NUMERICAL]
# 	9 : SumSquares [NUMERICAL]
# 	9 : DifferenceEntropy [NUMERICAL]
# 	8 : DifferenceAverage [NUMERICAL]
# 	7 : ClusterTendency [NUMERICAL]
#
# Attribute in nodes with depth <= 0:
# 	66 : Autocorrelation [NUMERICAL]
# 	32 : SumAverage [NUMERICAL]
# 	24 : JointAverage [NUMERICAL]
#
# Attribute in nodes with depth <= 1:
# 	73 : Imc2 [NUMERICAL]
# 	66 : Autocorrelation [NUMERICAL]
# 	51 : Correlation [NUMERICAL]
# 	33 : MCC [NUMERICAL]
# 	32 : SumAverage [NUMERICAL]
# 	26 : ClusterShade [NUMERICAL]
# 	25 : JointAverage [NUMERICAL]
# 	17 : Idn [NUMERICAL]
# 	13 : Imc1 [NUMERICAL]
# 	12 : JointEntropy [NUMERICAL]
# 	5 : ClusterProminence [NUMERICAL]
# 	4 : ClusterTendency [NUMERICAL]
# 	3 : Contrast [NUMERICAL]
# 	2 : MaximumProbability [NUMERICAL]
# 	2 : Idm [NUMERICAL]
# 	1 : SumSquares [NUMERICAL]
# 	1 : JointEnergy [NUMERICAL]
#
# Attribute in nodes with depth <= 2:
# 	121 : Imc2 [NUMERICAL]
# 	76 : Autocorrelation [NUMERICAL]
# 	64 : ClusterShade [NUMERICAL]
# 	53 : Correlation [NUMERICAL]
# 	49 : JointEntropy [NUMERICAL]
# 	47 : SumAverage [NUMERICAL]
# 	34 : MCC [NUMERICAL]
# 	33 : SumEntropy [NUMERICAL]
# 	31 : JointAverage [NUMERICAL]
# 	28 : Idn [NUMERICAL]
# 	27 : Imc1 [NUMERICAL]
# 	25 : MaximumProbability [NUMERICAL]
# 	25 : ClusterProminence [NUMERICAL]
# 	24 : JointEnergy [NUMERICAL]
# 	20 : InverseVariance [NUMERICAL]
# 	14 : Idm [NUMERICAL]
# 	8 : DifferenceVariance [NUMERICAL]
# 	8 : Contrast [NUMERICAL]
# 	6 : SumSquares [NUMERICAL]
# 	6 : Idmn [NUMERICAL]
# 	5 : DifferenceEntropy [NUMERICAL]
# 	5 : ClusterTendency [NUMERICAL]
#
# Attribute in nodes with depth <= 3:
# 	136 : Imc2 [NUMERICAL]
# 	122 : ClusterShade [NUMERICAL]
# 	94 : Autocorrelation [NUMERICAL]
# 	87 : JointEntropy [NUMERICAL]
# 	73 : SumAverage [NUMERICAL]
# 	59 : JointAverage [NUMERICAL]
# 	57 : Correlation [NUMERICAL]
# 	56 : SumEntropy [NUMERICAL]
# 	54 : JointEnergy [NUMERICAL]
# 	41 : MCC [NUMERICAL]
# 	34 : MaximumProbability [NUMERICAL]
# 	34 : Idm [NUMERICAL]
# 	32 : Imc1 [NUMERICAL]
# 	30 : InverseVariance [NUMERICAL]
# 	30 : Idn [NUMERICAL]
# 	26 : ClusterProminence [NUMERICAL]
# 	17 : Id [NUMERICAL]
# 	15 : Contrast [NUMERICAL]
# 	14 : DifferenceVariance [NUMERICAL]
# 	10 : Idmn [NUMERICAL]
# 	6 : SumSquares [NUMERICAL]
# 	6 : DifferenceEntropy [NUMERICAL]
# 	6 : DifferenceAverage [NUMERICAL]
# 	6 : ClusterTendency [NUMERICAL]
#
# Attribute in nodes with depth <= 5:
# 	169 : ClusterShade [NUMERICAL]
# 	141 : Imc2 [NUMERICAL]
# 	138 : Autocorrelation [NUMERICAL]
# 	109 : SumAverage [NUMERICAL]
# 	107 : JointEntropy [NUMERICAL]
# 	106 : JointAverage [NUMERICAL]
# 	81 : SumEntropy [NUMERICAL]
# 	67 : Correlation [NUMERICAL]
# 	62 : JointEnergy [NUMERICAL]
# 	50 : InverseVariance [NUMERICAL]
# 	45 : MCC [NUMERICAL]
# 	41 : Imc1 [NUMERICAL]
# 	41 : Idm [NUMERICAL]
# 	40 : MaximumProbability [NUMERICAL]
# 	36 : Idn [NUMERICAL]
# 	29 : ClusterProminence [NUMERICAL]
# 	28 : Id [NUMERICAL]
# 	18 : Contrast [NUMERICAL]
# 	16 : DifferenceVariance [NUMERICAL]
# 	14 : Idmn [NUMERICAL]
# 	9 : SumSquares [NUMERICAL]
# 	9 : DifferenceEntropy [NUMERICAL]
# 	8 : DifferenceAverage [NUMERICAL]
# 	7 : ClusterTendency [NUMERICAL]
#
# Condition type in nodes:
# 	1371 : HigherCondition
# Condition type in nodes with depth <= 0:
# 	122 : HigherCondition
# Condition type in nodes with depth <= 1:
# 	366 : HigherCondition
# Condition type in nodes with depth <= 2:
# 	709 : HigherCondition
# Condition type in nodes with depth <= 3:
# 	1045 : HigherCondition
# Condition type in nodes with depth <= 5:
# 	1371 : HigherCondition
#
# Training logs:
# Number of iteration to final model: 122
# 	Iter:1 train-loss:1.198797 valid-loss:1.212279  train-accuracy:0.995260 valid-accuracy:1.000000
# 	Iter:2 train-loss:1.045940 valid-loss:1.057256  train-accuracy:0.996445 valid-accuracy:1.000000
# 	Iter:3 train-loss:0.918562 valid-loss:0.928002  train-accuracy:0.995260 valid-accuracy:1.000000
# 	Iter:4 train-loss:0.810883 valid-loss:0.816842  train-accuracy:0.996445 valid-accuracy:1.000000
# 	Iter:5 train-loss:0.718984 valid-loss:0.723700  train-accuracy:0.995260 valid-accuracy:1.000000
# 	Iter:6 train-loss:0.639837 valid-loss:0.641736  train-accuracy:0.996445 valid-accuracy:1.000000
# 	Iter:16 train-loss:0.229389 valid-loss:0.216866  train-accuracy:0.996445 valid-accuracy:1.000000
# 	Iter:26 train-loss:0.088679 valid-loss:0.083805  train-accuracy:0.996445 valid-accuracy:1.000000
# 	Iter:36 train-loss:0.035901 valid-loss:0.036174  train-accuracy:0.998815 valid-accuracy:1.000000
# 	Iter:46 train-loss:0.014687 valid-loss:0.017075  train-accuracy:1.000000 valid-accuracy:1.000000
# 	Iter:56 train-loss:0.006045 valid-loss:0.008205  train-accuracy:1.000000 valid-accuracy:1.000000
# 	Iter:66 train-loss:0.002383 valid-loss:0.003320  train-accuracy:1.000000 valid-accuracy:1.000000
# 	Iter:76 train-loss:0.000924 valid-loss:0.001351  train-accuracy:1.000000 valid-accuracy:1.000000
# 	Iter:86 train-loss:0.000366 valid-loss:0.000571  train-accuracy:1.000000 valid-accuracy:1.000000
# 	Iter:96 train-loss:0.000145 valid-loss:0.000252  train-accuracy:1.000000 valid-accuracy:1.000000
# 	Iter:106 train-loss:0.000061 valid-loss:0.000149  train-accuracy:1.000000 valid-accuracy:1.000000
# 	Iter:116 train-loss:0.000030 valid-loss:0.000105  train-accuracy:1.000000 valid-accuracy:1.000000
# 	Iter:126 train-loss:0.000020 valid-loss:0.000105  train-accuracy:1.000000 valid-accuracy:1.000000
# 	Iter:136 train-loss:0.000015 valid-loss:0.000115  train-accuracy:1.000000 valid-accuracy:1.000000
# 	Iter:146 train-loss:0.000012 valid-loss:0.000127  train-accuracy:1.000000 valid-accuracy:1.000000

# %%
# Model features
model.make_inspector().features()
# Out:
# ["Autocorrelation" (1; #0),
#  "ClusterProminence" (1; #1),
#  "ClusterShade" (1; #2),
#  "ClusterTendency" (1; #3),
#  "Contrast" (1; #4),
#  "Correlation" (1; #5),
#  "DifferenceAverage" (1; #6),
#  "DifferenceEntropy" (1; #7),
#  "DifferenceVariance" (1; #8),
#  "Id" (1; #9),
#  "Idm" (1; #10),
#  "Idmn" (1; #11),
#  "Idn" (1; #12),
#  "Imc1" (1; #13),
#  "Imc2" (1; #14),
#  "InverseVariance" (1; #15),
#  "JointAverage" (1; #16),
#  "JointEnergy" (1; #17),
#  "JointEntropy" (1; #18),
#  "MCC" (1; #19),
#  "MaximumProbability" (1; #20),
#  "SumAverage" (1; #21),
#  "SumEntropy" (1; #22),
#  "SumSquares" (1; #23)]

# %%
# Feature importance
model.make_inspector().variable_importances()
# Out:
# {'INV_MEAN_MIN_DEPTH': [("Autocorrelation" (1; #0), 0.3812977567874945),
#   ("SumAverage" (1; #21), 0.26330718509791057),
#   ("Imc2" (1; #14), 0.25870414566214256),
#   ("JointAverage" (1; #16), 0.24523191047079637),
#   ("ClusterShade" (1; #2), 0.2412615770766364),
#   ("Correlation" (1; #5), 0.240118722985247),
#   ("JointEntropy" (1; #18), 0.2289944511262463),
#   ("MCC" (1; #19), 0.22090866529930858),
#   ("Idn" (1; #12), 0.2189706600369516),
#   ("SumEntropy" (1; #22), 0.21309034168051608),
#   ("JointEnergy" (1; #17), 0.21232752702552052),
#   ("Imc1" (1; #13), 0.21207908957724983),
#   ("MaximumProbability" (1; #20), 0.20894203420782362),
#   ("ClusterProminence" (1; #1), 0.20859315157027541),
#   ("InverseVariance" (1; #15), 0.2085089422507196),
#   ("Idm" (1; #10), 0.2067876213346431),
#   ("Idmn" (1; #11), 0.20557753108720928),
#   ("Contrast" (1; #4), 0.20557030198062246),
#   ("Id" (1; #9), 0.20527732520073821),
#   ("DifferenceVariance" (1; #8), 0.2047216682747941),
#   ("DifferenceEntropy" (1; #7), 0.20393551029487594),
#   ("DifferenceAverage" (1; #6), 0.203763224878664),
#   ("SumSquares" (1; #23), 0.20369701463518627),
#   ("ClusterTendency" (1; #3), 0.20364572641532633)],
#  'SUM_SCORE': [("JointAverage" (1; #16), 222.68632469869166),
#   ("SumAverage" (1; #21), 215.64543339239972),
#   ("Imc2" (1; #14), 128.7591545853683),
#   ("MCC" (1; #19), 9.728120631225663),
#   ("Imc1" (1; #13), 5.694467006756275),
#   ("Autocorrelation" (1; #0), 3.937111946491025),
#   ("Correlation" (1; #5), 2.34451587292173),
#   ("JointEntropy" (1; #18), 0.9667534056655163),
#   ("ClusterShade" (1; #2), 0.807642716790651),
#   ("Idm" (1; #10), 0.8027357123736203),
#   ("SumEntropy" (1; #22), 0.6187687532036651),
#   ("DifferenceEntropy" (1; #7), 0.4269662802921477),
#   ("MaximumProbability" (1; #20), 0.3966128152081899),
#   ("DifferenceVariance" (1; #8), 0.2682100416371355),
#   ("JointEnergy" (1; #17), 0.16788188755463807),
#   ("InverseVariance" (1; #15), 0.1414786224947527),
#   ("Contrast" (1; #4), 0.07439751786865509),
#   ("ClusterProminence" (1; #1), 0.06111804983096791),
#   ("Idmn" (1; #11), 0.04729271333446706),
#   ("Idn" (1; #12), 0.032866662226380176),
#   ("Id" (1; #9), 0.027297763962791568),
#   ("ClusterTendency" (1; #3), 0.02225787254342349),
#   ("SumSquares" (1; #23), 0.0033428713871897263),
#   ("DifferenceAverage" (1; #6), 0.0022223722947082485)],
#  'NUM_AS_ROOT': [("Autocorrelation" (1; #0), 66.0),
#   ("SumAverage" (1; #21), 32.0),
#   ("JointAverage" (1; #16), 24.0)],
#  'NUM_NODES': [("ClusterShade" (1; #2), 169.0),
#   ("Imc2" (1; #14), 141.0),
#   ("Autocorrelation" (1; #0), 138.0),
#   ("SumAverage" (1; #21), 109.0),
#   ("JointEntropy" (1; #18), 107.0),
#   ("JointAverage" (1; #16), 106.0),
#   ("SumEntropy" (1; #22), 81.0),
#   ("Correlation" (1; #5), 67.0),
#   ("JointEnergy" (1; #17), 62.0),
#   ("InverseVariance" (1; #15), 50.0),
#   ("MCC" (1; #19), 45.0),
#   ("Idm" (1; #10), 41.0),
#   ("Imc1" (1; #13), 41.0),
#   ("MaximumProbability" (1; #20), 40.0),
#   ("Idn" (1; #12), 36.0),
#   ("ClusterProminence" (1; #1), 29.0),
#   ("Id" (1; #9), 28.0),
#   ("Contrast" (1; #4), 18.0),
#   ("DifferenceVariance" (1; #8), 16.0),
#   ("Idmn" (1; #11), 14.0),
#   ("DifferenceEntropy" (1; #7), 9.0),
#   ("SumSquares" (1; #23), 9.0),
#   ("DifferenceAverage" (1; #6), 8.0),
#   ("ClusterTendency" (1; #3), 7.0)]}

# %%
# Model self evaluation
model.make_inspector().evaluation()
# Out:
# Evaluation(num_examples=None, accuracy=1.0, loss=0.00010325791663490236, rmse=None, ndcg=None, aucs=None, auuc=None, qini=None)

# %%
logs = model.make_inspector().training_logs()

plt.figure(figsize=(12, 4))
plt.subplot(1, 2, 1)
plt.plot([log.num_trees for log in logs], [log.evaluation.accuracy for log in logs])
plt.xlabel("Number of trees")
plt.ylabel("Accuracy (out-of-bag)")
plt.subplot(1, 2, 2)
plt.plot([log.num_trees for log in logs], [log.evaluation.loss for log in logs])
plt.xlabel("Number of trees")
plt.ylabel("Logloss (out-of-bag)")
plt.show()

# %% [markdown]
# Calculate the score of our hold-out validation dataset

# %%
predictions = model.predict(val_ds)
y_true      = validation_data["label"]

from sklearn.metrics import roc_auc_score
ROC_AUC = roc_auc_score(y_true, predictions)
print("The ROC AUC score is %.5f" % ROC_AUC )
# Out:
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 65ms/step
# The ROC AUC score is 0.99034

# %%
# Compute binary classification metrics with sklearn
import numpy as np
from sklearn.metrics import (
    accuracy_score,
    precision_score,
    recall_score,
    f1_score,
    roc_auc_score,
    average_precision_score,
    confusion_matrix,
    classification_report,
    matthews_corrcoef,
    log_loss,
    brier_score_loss,
)

# Get predictions (probabilities or class labels)
preds = model.predict(test_ds)
# If model outputs probabilities, convert to labels by threshold 0.5
if preds.ndim == 2:
    # For TFDF classification, preds may be class probabilities with shape (N, 2)
    if preds.shape[1] == 2:
        pos_probs = preds[:, 1]
    else:
        # If single-probability column (positive class)
        pos_probs = preds[:, -1]
    y_pred = (pos_probs >= 0.5).astype(int)
else:
    # Already class labels
    y_pred = preds.astype(int)
    pos_probs = None

# Ground truth labels (must be 0/1 integers)
y_true = test_data["label"].astype(int).to_numpy()

# Core metrics
metrics = {}
metrics["accuracy"] = accuracy_score(y_true, y_pred)
metrics["precision"] = precision_score(y_true, y_pred, zero_division=0)
metrics["recall"] = recall_score(y_true, y_pred, zero_division=0)
metrics["f1"] = f1_score(y_true, y_pred, zero_division=0)
metrics["mcc"] = matthews_corrcoef(y_true, y_pred)

# Probabilistic metrics (only if we have probabilities)
if pos_probs is not None:
    metrics["roc_auc"] = roc_auc_score(y_true, pos_probs)
    metrics["pr_auc"] = average_precision_score(y_true, pos_probs)
    metrics["log_loss"] = log_loss(y_true, pos_probs, labels=[0,1])
    metrics["brier_score"] = brier_score_loss(y_true, pos_probs)

# Confusion matrix and detailed report
cm = confusion_matrix(y_true, y_pred, labels=[0,1])
report = classification_report(y_true, y_pred, digits=4)

print("Sklearn binary metrics:")
for k, v in metrics.items():
    print(f"{k}: {v:.4f}")
print("\nConfusion matrix:\n", cm)
print("\nClassification report:\n", report)
# Out:
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 74ms/step
# Sklearn binary metrics:
# accuracy: 0.9863
# precision: 1.0000
# recall: 0.8000
# f1: 0.8889
# mcc: 0.8879
# roc_auc: 1.0000
# pr_auc: 1.0000
# log_loss: 0.0267
# brier_score: 0.0099
#
# Confusion matrix:
#  [[136   0]
#  [  2   8]]
#
# Classification report:
#                precision    recall  f1-score   support
#
#            0     0.9855    1.0000    0.9927       136
#            1     1.0000    0.8000    0.8889        10
#
#     accuracy                         0.9863       146
#    macro avg     0.9928    0.9000    0.9408       146
# weighted avg     0.9865    0.9863    0.9856       146
