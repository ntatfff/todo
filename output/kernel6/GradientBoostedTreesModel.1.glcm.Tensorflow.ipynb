# %%
# Import packages and modules
import numpy  as np
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow_decision_forests as tfdf

from sklearn.model_selection import train_test_split
# Out:
# 2026-08-12 05:39:54.801700: I tensorflow/core/util/port.cc:113] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2026-08-12 05:39:55.138313: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2026-08-12 05:39:59.497357: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
# Check the version of TensorFlow Decision Forests
print("Found TensorFlow Decision Forests v" + tfdf.__version__)
# Out:
# Found TensorFlow Decision Forests v1.9.1

# %%
datasetPath = 'dataset/firstorder/kernel5-radius5/dataset.csv'

# %%
# Parameters
datasetPath = "dataset/glcm/kernel6-radius6/1.dataset.csv"

# %%
# train/validation/test = 70/10/20
dataset = pd.read_csv(datasetPath)

train_data, temp_data = train_test_split(dataset, test_size=0.3, random_state=42)
validation_data, test_data = train_test_split(temp_data, test_size=2/3, random_state=42)

# %%
from sklearn.utils.class_weight import compute_class_weight

# tinh class weight tren tap train
classes = np.array([0, 1])
weights = compute_class_weight(class_weight="balanced", classes=classes, y=train_data["label"])
class_weight = {0: weights[0], 1: weights[1]}

# gan sample_weight cho tung dong
train_data["sample_weight"] = train_data["label"].map(class_weight)
validation_data["sample_weight"] = validation_data["label"].map(class_weight)
test_data["sample_weight"] = test_data["label"].map(class_weight)

# Convert the dataset into a TensorFlow dataset.
train_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    train_data, label="label", weight="sample_weight"
)         
val_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    validation_data, label="label", weight="sample_weight"
)
test_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    test_data, label="label", weight="sample_weight"
)
# Out:
# 2026-08-12 05:40:11.130352: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:984] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2026-08-12 05:40:11.132723: W tensorflow/core/common_runtime/gpu/gpu_device.cc:2251] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...

# %%
import keras

# %%
# %%time

# Train a Gradient Boosted Trees model.
model = tfdf.keras.GradientBoostedTreesModel()

# Add evaluation metrics
model.compile(
    metrics=["accuracy"]
)
model.fit(x=train_ds)

# # Train a Gradient Boosted Trees model.
# model = tfdf.keras.GradientBoostedTreesModel(num_trees=1500)
# model.fit(train_ds)
# Out:
# Use /tmp/tmp16099j_p as temporary training directory
# Reading training dataset...
# [WARNING 26-08-12 05:40:11.2818 UTC gradient_boosted_trees.cc:1840] "goss_alpha" set but "sampling_method" not equal to "GOSS".
# [WARNING 26-08-12 05:40:11.2822 UTC gradient_boosted_trees.cc:1851] "goss_beta" set but "sampling_method" not equal to "GOSS".
# [WARNING 26-08-12 05:40:11.2822 UTC gradient_boosted_trees.cc:1865] "selective_gradient_boosting_ratio" set but "sampling_method" not equal to "SELGB".
# Training dataset read in 0:00:02.450366. Found 450 examples.
# Training model...
# Model trained in 0:00:00.258311
# Compiling model...
# [INFO 26-08-12 05:40:14.0171 UTC kernel.cc:1233] Loading model from path /tmp/tmp16099j_p/model/ with prefix 9bb81a0cc82647ca
# [INFO 26-08-12 05:40:14.0189 UTC quick_scorer_extended.cc:911] The binary was compiled without AVX2 support, but your CPU supports it. Enable it for faster model inference.
# [INFO 26-08-12 05:40:14.0190 UTC abstract_model.cc:1362] Engine "GradientBoostedTreesQuickScorerExtended" built
# [INFO 26-08-12 05:40:14.0190 UTC kernel.cc:1061] Use fast generic engine
# Model compiled.
# CPU times: user 5.57 s, sys: 403 ms, total: 5.98 s
# Wall time: 5.7 s

# %%
# Evaluate the model
evaluate = model.evaluate(val_ds, return_dict=True)
print()

for name, value in evaluate.items():
    print(f"{name}: {value:.4f}")
# Out:
# WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 1/1 [==============================] - ETA: 0s - loss: 0.0000e+00 - accuracy: 0.9062
# 1/1 [==============================] - 6s 6s/step - loss: 0.0000e+00 - accuracy: 0.9062
# loss: 0.0000
# accuracy: 0.9062

# %%
# Model Summary
model.summary()
# Out:
# Model: "gradient_boosted_trees_model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
# =================================================================
# Total params: 1 (1.00 Byte)
# Trainable params: 0 (0.00 Byte)
# Non-trainable params: 1 (1.00 Byte)
# _________________________________________________________________
# Type: "GRADIENT_BOOSTED_TREES"
# Task: CLASSIFICATION
# Label: "__LABEL"
#
# Input Features (24):
# 	Autocorrelation
# 	ClusterProminence
# 	ClusterShade
# 	ClusterTendency
# 	Contrast
# 	Correlation
# 	DifferenceAverage
# 	DifferenceEntropy
# 	DifferenceVariance
# 	Id
# 	Idm
# 	Idmn
# 	Idn
# 	Imc1
# 	Imc2
# 	InverseVariance
# 	JointAverage
# 	JointEnergy
# 	JointEntropy
# 	MCC
# 	MaximumProbability
# 	SumAverage
# 	SumEntropy
# 	SumSquares
#
# Trained with weights
#
# Variable Importance: INV_MEAN_MIN_DEPTH:
#     1.    "Autocorrelation"  0.422975 ################
#     2.               "Imc2"  0.254662 ####
#     3.                "MCC"  0.249966 ####
#     4.         "SumAverage"  0.236989 ###
#     5. "DifferenceVariance"  0.224839 ##
#     6.       "JointAverage"  0.223527 ##
#     7.         "SumEntropy"  0.220442 ##
#     8.  "DifferenceEntropy"  0.207595 #
#     9.    "InverseVariance"  0.200640
#    10.           "Contrast"  0.193910
#    11.                "Idm"  0.191798
#    12.        "JointEnergy"  0.190453
#    13.       "ClusterShade"  0.189997
#    14.               "Idmn"  0.189843
#    15.       "JointEntropy"  0.189802
#    16. "MaximumProbability"  0.189380
#    17.                 "Id"  0.189233
#    18.        "Correlation"  0.188937
#    19.         "SumSquares"  0.188186
#    20.  "DifferenceAverage"  0.188128
#    21.               "Imc1"  0.187820
#    22.                "Idn"  0.187552
#    23.  "ClusterProminence"  0.187041
#    24.    "ClusterTendency"  0.186997
#
# Variable Importance: NUM_AS_ROOT:
#     1. "Autocorrelation" 17.000000 ################
#     2.      "SumAverage"  6.000000 ##
#     3.    "JointAverage"  4.000000
#
# Variable Importance: NUM_NODES:
#     1.    "Autocorrelation" 49.000000 ################
#     2.         "SumEntropy" 46.000000 ###############
#     3.                "MCC" 38.000000 ############
#     4. "DifferenceVariance" 35.000000 ###########
#     5.    "InverseVariance" 30.000000 #########
#     6.               "Imc2" 28.000000 #########
#     7.  "DifferenceEntropy" 22.000000 #######
#     8.         "SumAverage" 22.000000 #######
#     9.       "JointAverage" 21.000000 ######
#    10.        "JointEnergy" 15.000000 ####
#    11.       "ClusterShade" 14.000000 ####
#    12. "MaximumProbability" 13.000000 ####
#    13.                "Idm" 12.000000 ###
#    14.       "JointEntropy" 11.000000 ###
#    15.           "Contrast" 10.000000 ###
#    16.                 "Id" 10.000000 ###
#    17.               "Idmn"  9.000000 ##
#    18.               "Imc1"  8.000000 ##
#    19.                "Idn"  6.000000 #
#    20.  "DifferenceAverage"  5.000000 #
#    21.        "Correlation"  3.000000
#    22.         "SumSquares"  3.000000
#    23.    "ClusterTendency"  2.000000
#    24.  "ClusterProminence"  1.000000
#
# Variable Importance: SUM_SCORE:
#     1.    "Autocorrelation" 357.081376 ################
#     2.                "MCC" 29.301194 #
#     3.               "Imc2" 25.176712 #
#     4.         "SumAverage" 22.729759 #
#     5.    "InverseVariance" 19.519129
#     6. "DifferenceVariance" 15.051104
#     7.  "DifferenceEntropy" 13.715886
#     8.       "JointAverage" 10.971575
#     9.         "SumEntropy" 10.701533
#    10.                 "Id"  9.128579
#    11. "MaximumProbability"  2.836033
#    12.                "Idm"  2.007389
#    13.               "Idmn"  1.440373
#    14.        "JointEnergy"  1.064220
#    15.       "ClusterShade"  0.952965
#    16.         "SumSquares"  0.926915
#    17.           "Contrast"  0.874405
#    18.    "ClusterTendency"  0.545508
#    19.        "Correlation"  0.463971
#    20.               "Imc1"  0.395993
#    21.       "JointEntropy"  0.240684
#    22.  "DifferenceAverage"  0.239458
#    23.                "Idn"  0.160169
#    24.  "ClusterProminence"  0.001596
#
#
#
# Loss: BINOMIAL_LOG_LIKELIHOOD
# Validation loss value: 0.565937
# Number of trees per iteration: 1
# Node format: NOT_SET
# Number of trees: 27
# Total number of nodes: 853
#
# Number of nodes by tree:
# Count: 27 Average: 31.5926 StdDev: 4.51548
# Min: 25 Max: 39 Ignored: 0
# ----------------------------------------------
# [ 25, 26) 3  11.11%  11.11% ####
# [ 26, 27) 0   0.00%  11.11%
# [ 27, 28) 7  25.93%  37.04% ##########
# [ 28, 29) 0   0.00%  37.04%
# [ 29, 30) 1   3.70%  40.74% #
# [ 30, 31) 0   0.00%  40.74%
# [ 31, 32) 2   7.41%  48.15% ###
# [ 32, 33) 0   0.00%  48.15%
# [ 33, 34) 3  11.11%  59.26% ####
# [ 34, 35) 0   0.00%  59.26%
# [ 35, 36) 5  18.52%  77.78% #######
# [ 36, 37) 0   0.00%  77.78%
# [ 37, 38) 5  18.52%  96.30% #######
# [ 38, 39) 0   0.00%  96.30%
# [ 39, 39] 1   3.70% 100.00% #
#
# Depth by leafs:
# Count: 440 Average: 4.37727 StdDev: 0.908761
# Min: 2 Max: 5 Ignored: 0
# ----------------------------------------------
# [ 2, 3)  20   4.55%   4.55% #
# [ 3, 4)  70  15.91%  20.45% ###
# [ 4, 5)  74  16.82%  37.27% ###
# [ 5, 5] 276  62.73% 100.00% ##########
#
# Number of training obs by leaf:
# Count: 440 Average: 24.975 StdDev: 57.4027
# Min: 5 Max: 290 Ignored: 0
# ----------------------------------------------
# [   5,  19) 369  83.86%  83.86% ##########
# [  19,  33)  21   4.77%  88.64% #
# [  33,  47)  12   2.73%  91.36%
# [  47,  62)   0   0.00%  91.36%
# [  62,  76)   0   0.00%  91.36%
# [  76,  90)   1   0.23%  91.59%
# [  90, 105)   9   2.05%  93.64%
# [ 105, 119)   1   0.23%  93.86%
# [ 119, 133)   0   0.00%  93.86%
# [ 133, 148)   0   0.00%  93.86%
# [ 148, 162)   0   0.00%  93.86%
# [ 162, 176)   0   0.00%  93.86%
# [ 176, 190)   4   0.91%  94.77%
# [ 190, 205)   7   1.59%  96.36%
# [ 205, 219)   0   0.00%  96.36%
# [ 219, 233)   0   0.00%  96.36%
# [ 233, 248)   1   0.23%  96.59%
# [ 248, 262)   5   1.14%  97.73%
# [ 262, 276)   3   0.68%  98.41%
# [ 276, 290]   7   1.59% 100.00%
#
# Attribute in nodes:
# 	49 : Autocorrelation [NUMERICAL]
# 	46 : SumEntropy [NUMERICAL]
# 	38 : MCC [NUMERICAL]
# 	35 : DifferenceVariance [NUMERICAL]
# 	30 : InverseVariance [NUMERICAL]
# 	28 : Imc2 [NUMERICAL]
# 	22 : SumAverage [NUMERICAL]
# 	22 : DifferenceEntropy [NUMERICAL]
# 	21 : JointAverage [NUMERICAL]
# 	15 : JointEnergy [NUMERICAL]
# 	14 : ClusterShade [NUMERICAL]
# 	13 : MaximumProbability [NUMERICAL]
# 	12 : Idm [NUMERICAL]
# 	11 : JointEntropy [NUMERICAL]
# 	10 : Id [NUMERICAL]
# 	10 : Contrast [NUMERICAL]
# 	9 : Idmn [NUMERICAL]
# 	8 : Imc1 [NUMERICAL]
# 	6 : Idn [NUMERICAL]
# 	5 : DifferenceAverage [NUMERICAL]
# 	3 : SumSquares [NUMERICAL]
# 	3 : Correlation [NUMERICAL]
# 	2 : ClusterTendency [NUMERICAL]
# 	1 : ClusterProminence [NUMERICAL]
#
# Attribute in nodes with depth <= 0:
# 	17 : Autocorrelation [NUMERICAL]
# 	6 : SumAverage [NUMERICAL]
# 	4 : JointAverage [NUMERICAL]
#
# Attribute in nodes with depth <= 1:
# 	24 : MCC [NUMERICAL]
# 	20 : Autocorrelation [NUMERICAL]
# 	18 : Imc2 [NUMERICAL]
# 	7 : SumEntropy [NUMERICAL]
# 	6 : SumAverage [NUMERICAL]
# 	4 : JointAverage [NUMERICAL]
# 	1 : DifferenceEntropy [NUMERICAL]
# 	1 : Correlation [NUMERICAL]
#
# Attribute in nodes with depth <= 2:
# 	25 : MCC [NUMERICAL]
# 	24 : Autocorrelation [NUMERICAL]
# 	22 : DifferenceVariance [NUMERICAL]
# 	20 : Imc2 [NUMERICAL]
# 	14 : DifferenceEntropy [NUMERICAL]
# 	12 : SumAverage [NUMERICAL]
# 	11 : InverseVariance [NUMERICAL]
# 	10 : JointAverage [NUMERICAL]
# 	9 : SumEntropy [NUMERICAL]
# 	8 : Contrast [NUMERICAL]
# 	2 : SumSquares [NUMERICAL]
# 	2 : JointEnergy [NUMERICAL]
# 	2 : Imc1 [NUMERICAL]
# 	2 : Idmn [NUMERICAL]
# 	2 : Correlation [NUMERICAL]
# 	1 : MaximumProbability [NUMERICAL]
# 	1 : Idm [NUMERICAL]
# 	1 : DifferenceAverage [NUMERICAL]
# 	1 : ClusterShade [NUMERICAL]
#
# Attribute in nodes with depth <= 3:
# 	34 : Autocorrelation [NUMERICAL]
# 	32 : MCC [NUMERICAL]
# 	30 : DifferenceVariance [NUMERICAL]
# 	24 : SumEntropy [NUMERICAL]
# 	24 : InverseVariance [NUMERICAL]
# 	24 : Imc2 [NUMERICAL]
# 	16 : DifferenceEntropy [NUMERICAL]
# 	15 : SumAverage [NUMERICAL]
# 	12 : JointAverage [NUMERICAL]
# 	11 : JointEnergy [NUMERICAL]
# 	9 : Contrast [NUMERICAL]
# 	8 : Idm [NUMERICAL]
# 	6 : MaximumProbability [NUMERICAL]
# 	6 : Idmn [NUMERICAL]
# 	6 : ClusterShade [NUMERICAL]
# 	4 : JointEntropy [NUMERICAL]
# 	4 : Id [NUMERICAL]
# 	3 : DifferenceAverage [NUMERICAL]
# 	2 : SumSquares [NUMERICAL]
# 	2 : Imc1 [NUMERICAL]
# 	2 : Correlation [NUMERICAL]
# 	1 : ClusterProminence [NUMERICAL]
#
# Attribute in nodes with depth <= 5:
# 	49 : Autocorrelation [NUMERICAL]
# 	46 : SumEntropy [NUMERICAL]
# 	38 : MCC [NUMERICAL]
# 	35 : DifferenceVariance [NUMERICAL]
# 	30 : InverseVariance [NUMERICAL]
# 	28 : Imc2 [NUMERICAL]
# 	22 : SumAverage [NUMERICAL]
# 	22 : DifferenceEntropy [NUMERICAL]
# 	21 : JointAverage [NUMERICAL]
# 	15 : JointEnergy [NUMERICAL]
# 	14 : ClusterShade [NUMERICAL]
# 	13 : MaximumProbability [NUMERICAL]
# 	12 : Idm [NUMERICAL]
# 	11 : JointEntropy [NUMERICAL]
# 	10 : Id [NUMERICAL]
# 	10 : Contrast [NUMERICAL]
# 	9 : Idmn [NUMERICAL]
# 	8 : Imc1 [NUMERICAL]
# 	6 : Idn [NUMERICAL]
# 	5 : DifferenceAverage [NUMERICAL]
# 	3 : SumSquares [NUMERICAL]
# 	3 : Correlation [NUMERICAL]
# 	2 : ClusterTendency [NUMERICAL]
# 	1 : ClusterProminence [NUMERICAL]
#
# Condition type in nodes:
# 	413 : HigherCondition
# Condition type in nodes with depth <= 0:
# 	27 : HigherCondition
# Condition type in nodes with depth <= 1:
# 	81 : HigherCondition
# Condition type in nodes with depth <= 2:
# 	169 : HigherCondition
# Condition type in nodes with depth <= 3:
# 	275 : HigherCondition
# Condition type in nodes with depth <= 5:
# 	413 : HigherCondition
#
# Training logs:
# Number of iteration to final model: 27
# 	Iter:1 train-loss:1.209288 valid-loss:1.259071  train-accuracy:0.976878 valid-accuracy:0.867734
# 	Iter:2 train-loss:1.064331 valid-loss:1.151155  train-accuracy:0.984104 valid-accuracy:0.867734
# 	Iter:3 train-loss:0.943398 valid-loss:1.066473  train-accuracy:0.982659 valid-accuracy:0.867734
# 	Iter:4 train-loss:0.841174 valid-loss:0.998432  train-accuracy:0.984104 valid-accuracy:0.867734
# 	Iter:5 train-loss:0.753775 valid-loss:0.943648  train-accuracy:0.982659 valid-accuracy:0.867734
# 	Iter:6 train-loss:0.678535 valid-loss:0.900391  train-accuracy:0.984104 valid-accuracy:0.867734
# 	Iter:16 train-loss:0.258715 valid-loss:0.714642  train-accuracy:0.991329 valid-accuracy:0.890985
# 	Iter:26 train-loss:0.104039 valid-loss:0.581545  train-accuracy:0.997110 valid-accuracy:0.890985
# 	Iter:36 train-loss:0.045503 valid-loss:0.619432  train-accuracy:1.000000 valid-accuracy:0.742710
# 	Iter:46 train-loss:0.020580 valid-loss:0.729750  train-accuracy:1.000000 valid-accuracy:0.816848
# 	Iter:56 train-loss:0.010138 valid-loss:0.834503  train-accuracy:1.000000 valid-accuracy:0.816848

# %%
# Model features
model.make_inspector().features()
# Out:
# ["Autocorrelation" (1; #0),
#  "ClusterProminence" (1; #1),
#  "ClusterShade" (1; #2),
#  "ClusterTendency" (1; #3),
#  "Contrast" (1; #4),
#  "Correlation" (1; #5),
#  "DifferenceAverage" (1; #6),
#  "DifferenceEntropy" (1; #7),
#  "DifferenceVariance" (1; #8),
#  "Id" (1; #9),
#  "Idm" (1; #10),
#  "Idmn" (1; #11),
#  "Idn" (1; #12),
#  "Imc1" (1; #13),
#  "Imc2" (1; #14),
#  "InverseVariance" (1; #15),
#  "JointAverage" (1; #16),
#  "JointEnergy" (1; #17),
#  "JointEntropy" (1; #18),
#  "MCC" (1; #19),
#  "MaximumProbability" (1; #20),
#  "SumAverage" (1; #21),
#  "SumEntropy" (1; #22),
#  "SumSquares" (1; #23)]

# %%
# Feature importance
model.make_inspector().variable_importances()
# Out:
# {'INV_MEAN_MIN_DEPTH': [("Autocorrelation" (1; #0), 0.42297450682546156),
#   ("Imc2" (1; #14), 0.25466163888814913),
#   ("MCC" (1; #19), 0.24996615690054408),
#   ("SumAverage" (1; #21), 0.2369889065585144),
#   ("DifferenceVariance" (1; #8), 0.22483883659915974),
#   ("JointAverage" (1; #16), 0.22352744648188763),
#   ("SumEntropy" (1; #22), 0.22044182532393794),
#   ("DifferenceEntropy" (1; #7), 0.20759505371661371),
#   ("InverseVariance" (1; #15), 0.20064043304529203),
#   ("Contrast" (1; #4), 0.19390971327920725),
#   ("Idm" (1; #10), 0.1917977297341285),
#   ("JointEnergy" (1; #17), 0.19045283090007417),
#   ("ClusterShade" (1; #2), 0.18999684777761822),
#   ("Idmn" (1; #11), 0.18984284804180931),
#   ("JointEntropy" (1; #18), 0.1898022943257382),
#   ("MaximumProbability" (1; #20), 0.18938036018788032),
#   ("Id" (1; #9), 0.18923255879549736),
#   ("Correlation" (1; #5), 0.18893668145161435),
#   ("SumSquares" (1; #23), 0.18818557458994578),
#   ("DifferenceAverage" (1; #6), 0.18812783940372885),
#   ("Imc1" (1; #13), 0.18782032098304732),
#   ("Idn" (1; #12), 0.18755159870890817),
#   ("ClusterProminence" (1; #1), 0.1870407783471653),
#   ("ClusterTendency" (1; #3), 0.18699723510607846)],
#  'NUM_AS_ROOT': [("Autocorrelation" (1; #0), 17.0),
#   ("SumAverage" (1; #21), 6.0),
#   ("JointAverage" (1; #16), 4.0)],
#  'SUM_SCORE': [("Autocorrelation" (1; #0), 357.0813760617652),
#   ("MCC" (1; #19), 29.301194253064885),
#   ("Imc2" (1; #14), 25.176712388122947),
#   ("SumAverage" (1; #21), 22.729758754640457),
#   ("InverseVariance" (1; #15), 19.51912882954446),
#   ("DifferenceVariance" (1; #8), 15.051104300074662),
#   ("DifferenceEntropy" (1; #7), 13.715885623654987),
#   ("JointAverage" (1; #16), 10.97157478183483),
#   ("SumEntropy" (1; #22), 10.701533293474313),
#   ("Id" (1; #9), 9.128578940053943),
#   ("MaximumProbability" (1; #20), 2.8360334081479603),
#   ("Idm" (1; #10), 2.0073886258436366),
#   ("Idmn" (1; #11), 1.4403729390626758),
#   ("JointEnergy" (1; #17), 1.064219862280015),
#   ("ClusterShade" (1; #2), 0.9529651137169212),
#   ("SumSquares" (1; #23), 0.9269145834611463),
#   ("Contrast" (1; #4), 0.8744048808240865),
#   ("ClusterTendency" (1; #3), 0.5455078915360092),
#   ("Correlation" (1; #5), 0.4639713726392523),
#   ("Imc1" (1; #13), 0.39599276414301704),
#   ("JointEntropy" (1; #18), 0.24068350545011635),
#   ("DifferenceAverage" (1; #6), 0.2394583770879547),
#   ("Idn" (1; #12), 0.1601693841019403),
#   ("ClusterProminence" (1; #1), 0.0015964256682596961)],
#  'NUM_NODES': [("Autocorrelation" (1; #0), 49.0),
#   ("SumEntropy" (1; #22), 46.0),
#   ("MCC" (1; #19), 38.0),
#   ("DifferenceVariance" (1; #8), 35.0),
#   ("InverseVariance" (1; #15), 30.0),
#   ("Imc2" (1; #14), 28.0),
#   ("DifferenceEntropy" (1; #7), 22.0),
#   ("SumAverage" (1; #21), 22.0),
#   ("JointAverage" (1; #16), 21.0),
#   ("JointEnergy" (1; #17), 15.0),
#   ("ClusterShade" (1; #2), 14.0),
#   ("MaximumProbability" (1; #20), 13.0),
#   ("Idm" (1; #10), 12.0),
#   ("JointEntropy" (1; #18), 11.0),
#   ("Contrast" (1; #4), 10.0),
#   ("Id" (1; #9), 10.0),
#   ("Idmn" (1; #11), 9.0),
#   ("Imc1" (1; #13), 8.0),
#   ("Idn" (1; #12), 6.0),
#   ("DifferenceAverage" (1; #6), 5.0),
#   ("Correlation" (1; #5), 3.0),
#   ("SumSquares" (1; #23), 3.0),
#   ("ClusterTendency" (1; #3), 2.0),
#   ("ClusterProminence" (1; #1), 1.0)]}

# %%
# Model self evaluation
model.make_inspector().evaluation()
# Out:
# Evaluation(num_examples=None, accuracy=0.8909853100776672, loss=0.5659372210502625, rmse=None, ndcg=None, aucs=None, auuc=None, qini=None)

# %%
logs = model.make_inspector().training_logs()

plt.figure(figsize=(12, 4))
plt.subplot(1, 2, 1)
plt.plot([log.num_trees for log in logs], [log.evaluation.accuracy for log in logs])
plt.xlabel("Number of trees")
plt.ylabel("Accuracy (out-of-bag)")
plt.subplot(1, 2, 2)
plt.plot([log.num_trees for log in logs], [log.evaluation.loss for log in logs])
plt.xlabel("Number of trees")
plt.ylabel("Logloss (out-of-bag)")
plt.show()

# %% [markdown]
# Calculate the score of our hold-out validation dataset

# %%
predictions = model.predict(val_ds)
y_true      = validation_data["label"]

from sklearn.metrics import roc_auc_score
ROC_AUC = roc_auc_score(y_true, predictions)
print("The ROC AUC score is %.5f" % ROC_AUC )
# Out:
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 62ms/step
# The ROC AUC score is 0.94854

# %%
# Compute binary classification metrics with sklearn
import numpy as np
from sklearn.metrics import (
    accuracy_score,
    precision_score,
    recall_score,
    f1_score,
    roc_auc_score,
    average_precision_score,
    confusion_matrix,
    classification_report,
    matthews_corrcoef,
    log_loss,
    brier_score_loss,
)

# Get predictions (probabilities or class labels)
preds = model.predict(test_ds)
# If model outputs probabilities, convert to labels by threshold 0.5
if preds.ndim == 2:
    # For TFDF classification, preds may be class probabilities with shape (N, 2)
    if preds.shape[1] == 2:
        pos_probs = preds[:, 1]
    else:
        # If single-probability column (positive class)
        pos_probs = preds[:, -1]
    y_pred = (pos_probs >= 0.5).astype(int)
else:
    # Already class labels
    y_pred = preds.astype(int)
    pos_probs = None

# Ground truth labels (must be 0/1 integers)
y_true = test_data["label"].astype(int).to_numpy()

# Core metrics
metrics = {}
metrics["accuracy"] = accuracy_score(y_true, y_pred)
metrics["precision"] = precision_score(y_true, y_pred, zero_division=0)
metrics["recall"] = recall_score(y_true, y_pred, zero_division=0)
metrics["f1"] = f1_score(y_true, y_pred, zero_division=0)
metrics["mcc"] = matthews_corrcoef(y_true, y_pred)

# Probabilistic metrics (only if we have probabilities)
if pos_probs is not None:
    metrics["roc_auc"] = roc_auc_score(y_true, pos_probs)
    metrics["pr_auc"] = average_precision_score(y_true, pos_probs)
    metrics["log_loss"] = log_loss(y_true, pos_probs, labels=[0,1])
    metrics["brier_score"] = brier_score_loss(y_true, pos_probs)

# Confusion matrix and detailed report
cm = confusion_matrix(y_true, y_pred, labels=[0,1])
report = classification_report(y_true, y_pred, digits=4)

print("Sklearn binary metrics:")
for k, v in metrics.items():
    print(f"{k}: {v:.4f}")
print("\nConfusion matrix:\n", cm)
print("\nClassification report:\n", report)
# Out:
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 63ms/step
# Sklearn binary metrics:
# accuracy: 0.9535
# precision: 0.8000
# recall: 0.8889
# f1: 0.8421
# mcc: 0.8165
# roc_auc: 0.9374
# pr_auc: 0.8969
# log_loss: 0.1498
# brier_score: 0.0371
#
# Confusion matrix:
#  [[107   4]
#  [  2  16]]
#
# Classification report:
#                precision    recall  f1-score   support
#
#            0     0.9817    0.9640    0.9727       111
#            1     0.8000    0.8889    0.8421        18
#
#     accuracy                         0.9535       129
#    macro avg     0.8908    0.9264    0.9074       129
# weighted avg     0.9563    0.9535    0.9545       129
