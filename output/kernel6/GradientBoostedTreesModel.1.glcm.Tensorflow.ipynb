# %%
# Import packages and modules
import numpy  as np
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow_decision_forests as tfdf

from sklearn.model_selection import train_test_split
# Out:
# 2026-08-10 17:14:45.662863: I tensorflow/core/util/port.cc:113] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2026-08-10 17:14:46.059293: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2026-08-10 17:14:50.783715: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
# Check the version of TensorFlow Decision Forests
print("Found TensorFlow Decision Forests v" + tfdf.__version__)
# Out:
# Found TensorFlow Decision Forests v1.9.1

# %%
datasetPath = 'dataset/firstorder/kernel5-radius5/dataset.csv'

# %%
# Parameters
datasetPath = "dataset/glcm/kernel6-radius6/dataset.1p.csv"

# %%
# train/validation/test = 70/10/20
dataset = pd.read_csv(datasetPath)

train_data, temp_data = train_test_split(dataset, test_size=0.3, random_state=42)
validation_data, test_data = train_test_split(temp_data, test_size=2/3, random_state=42)

# %%
from sklearn.utils.class_weight import compute_class_weight

# tinh class weight tren tap train
classes = np.array([0, 1])
weights = compute_class_weight(class_weight="balanced", classes=classes, y=train_data["label"])
class_weight = {0: weights[0], 1: weights[1]}

# gan sample_weight cho tung dong
train_data["sample_weight"] = train_data["label"].map(class_weight)
validation_data["sample_weight"] = validation_data["label"].map(class_weight)
test_data["sample_weight"] = test_data["label"].map(class_weight)

# Convert the dataset into a TensorFlow dataset.
train_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    train_data, label="label", weight="sample_weight"
)         
val_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    validation_data, label="label", weight="sample_weight"
)
test_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    test_data, label="label", weight="sample_weight"
)
# Out:
# 2026-08-10 17:15:05.713737: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:984] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2026-08-10 17:15:05.714984: W tensorflow/core/common_runtime/gpu/gpu_device.cc:2251] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...

# %%
import keras

# %%
# %%time

# Train a Gradient Boosted Trees model.
model = tfdf.keras.GradientBoostedTreesModel()

# Add evaluation metrics
model.compile(
    metrics=["accuracy"]
)
model.fit(x=train_ds)

# # Train a Gradient Boosted Trees model.
# model = tfdf.keras.GradientBoostedTreesModel(num_trees=1500)
# model.fit(train_ds)
# Out:
# Use /tmp/tmp2tnglp7z as temporary training directory
# [WARNING 26-08-10 17:15:05.9193 UTC gradient_boosted_trees.cc:1840] "goss_alpha" set but "sampling_method" not equal to "GOSS".
# [WARNING 26-08-10 17:15:05.9196 UTC gradient_boosted_trees.cc:1851] "goss_beta" set but "sampling_method" not equal to "GOSS".
# [WARNING 26-08-10 17:15:05.9196 UTC gradient_boosted_trees.cc:1865] "selective_gradient_boosting_ratio" set but "sampling_method" not equal to "SELGB".
# Reading training dataset...
# Training dataset read in 0:00:02.606623. Found 777 examples.
# Training model...
# Model trained in 0:00:01.765125
# Compiling model...
# [INFO 26-08-10 17:15:10.3073 UTC kernel.cc:1233] Loading model from path /tmp/tmp2tnglp7z/model/ with prefix 0636df3d8a584f40
# [INFO 26-08-10 17:15:10.3167 UTC quick_scorer_extended.cc:911] The binary was compiled without AVX2 support, but your CPU supports it. Enable it for faster model inference.
# [INFO 26-08-10 17:15:10.3175 UTC abstract_model.cc:1362] Engine "GradientBoostedTreesQuickScorerExtended" built
# [INFO 26-08-10 17:15:10.3175 UTC kernel.cc:1061] Use fast generic engine
# Model compiled.
# CPU times: user 7.78 s, sys: 2.64 s, total: 10.4 s
# Wall time: 7.6 s

# %%
# Evaluate the model
evaluate = model.evaluate(val_ds, return_dict=True)
print()

for name, value in evaluate.items():
    print(f"{name}: {value:.4f}")
# Out:
# WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 1/1 [==============================] - ETA: 0s - loss: 0.0000e+00 - accuracy: 1.0000
# 1/1 [==============================] - 3s 3s/step - loss: 0.0000e+00 - accuracy: 1.0000
# loss: 0.0000
# accuracy: 1.0000

# %%
# Model Summary
model.summary()
# Out:
# Model: "gradient_boosted_trees_model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
# =================================================================
# Total params: 1 (1.00 Byte)
# Trainable params: 0 (0.00 Byte)
# Non-trainable params: 1 (1.00 Byte)
# _________________________________________________________________
# Type: "GRADIENT_BOOSTED_TREES"
# Task: CLASSIFICATION
# Label: "__LABEL"
#
# Input Features (42):
# 	10Percentile
# 	90Percentile
# 	Autocorrelation
# 	ClusterProminence
# 	ClusterShade
# 	ClusterTendency
# 	Contrast
# 	Correlation
# 	DifferenceAverage
# 	DifferenceEntropy
# 	DifferenceVariance
# 	Energy
# 	Entropy
# 	Id
# 	Idm
# 	Idmn
# 	Idn
# 	Imc1
# 	Imc2
# 	InterquartileRange
# 	InverseVariance
# 	JointAverage
# 	JointEnergy
# 	JointEntropy
# 	Kurtosis
# 	MCC
# 	Maximum
# 	MaximumProbability
# 	Mean
# 	MeanAbsoluteDeviation
# 	Median
# 	Minimum
# 	Range
# 	RobustMeanAbsoluteDeviation
# 	RootMeanSquared
# 	Skewness
# 	SumAverage
# 	SumEntropy
# 	SumSquares
# 	TotalEnergy
# 	Uniformity
# 	Variance
#
# Trained with weights
#
# Variable Importance: INV_MEAN_MIN_DEPTH:
#     1.           "ClusterProminence"  0.403042 ################
#     2.                         "Idm"  0.305714 ########
#     3.                 "JointEnergy"  0.266588 #####
#     4.                    "Skewness"  0.248586 ###
#     5.                 "TotalEnergy"  0.215150 #
#     6.                "ClusterShade"  0.212788
#     7.                      "Energy"  0.212788
#     8.                     "Minimum"  0.210213
#     9.                        "Mean"  0.209511
#    10.                          "Id"  0.209032
#    11.                        "Imc1"  0.208728
#    12.       "MeanAbsoluteDeviation"  0.208276
#    13. "RobustMeanAbsoluteDeviation"  0.207027
#    14.             "ClusterTendency"  0.204516
#    15.          "InterquartileRange"  0.204285
#    16.          "DifferenceVariance"  0.203823
#    17.                  "SumEntropy"  0.203679
#    18.                "10Percentile"  0.203575
#    19.                    "Variance"  0.203056
#    20.                 "Correlation"  0.202973
#    21.             "RootMeanSquared"  0.202640
#    22.                    "Kurtosis"  0.202462
#    23.           "DifferenceEntropy"  0.202407
#    24.                       "Range"  0.202343
#    25.                "JointEntropy"  0.202080
#    26.                         "Idn"  0.202057
#    27.             "Autocorrelation"  0.202034
#    28.          "MaximumProbability"  0.202014
#    29.                    "Contrast"  0.201921
#    30.                "JointAverage"  0.201818
#    31.             "InverseVariance"  0.201788
#    32.                      "Median"  0.201774
#    33.           "DifferenceAverage"  0.201712
#    34.                        "Idmn"  0.201708
#    35.                  "SumSquares"  0.201556
#    36.                     "Entropy"  0.201528
#    37.                "90Percentile"  0.201477
#    38.                        "Imc2"  0.201472
#    39.                  "SumAverage"  0.201316
#    40.                     "Maximum"  0.201313
#    41.                         "MCC"  0.201172
#    42.                  "Uniformity"  0.201047
#
# Variable Importance: NUM_AS_ROOT:
#     1.  "ClusterProminence" 161.000000 ################
#     2.        "JointEnergy" 107.000000 ##########
#     3.        "TotalEnergy" 15.000000 #
#     4.             "Energy" 13.000000
#     5. "InterquartileRange"  4.000000
#
# Variable Importance: NUM_NODES:
#     1.                         "Idm" 355.000000 ################
#     2.                    "Skewness" 344.000000 ###############
#     3.                        "Imc1" 307.000000 #############
#     4.                 "JointEnergy" 285.000000 ############
#     5.                     "Minimum" 239.000000 ##########
#     6.           "ClusterProminence" 238.000000 ##########
#     7.                        "Mean" 218.000000 #########
#     8.                "ClusterShade" 208.000000 #########
#     9.          "DifferenceVariance" 188.000000 ########
#    10. "RobustMeanAbsoluteDeviation" 152.000000 ######
#    11.       "MeanAbsoluteDeviation" 125.000000 #####
#    12.                "10Percentile" 114.000000 ####
#    13.                          "Id" 111.000000 ####
#    14.                  "SumEntropy" 90.000000 ###
#    15.                       "Range" 86.000000 ###
#    16.             "ClusterTendency" 85.000000 ###
#    17.           "DifferenceEntropy" 76.000000 ##
#    18.                    "Kurtosis" 66.000000 ##
#    19.                 "TotalEnergy" 65.000000 ##
#    20.                    "Variance" 64.000000 ##
#    21.                    "Contrast" 61.000000 ##
#    22.          "InterquartileRange" 59.000000 ##
#    23.                      "Energy" 57.000000 #
#    24.                         "Idn" 57.000000 #
#    25.             "Autocorrelation" 52.000000 #
#    26.                "JointEntropy" 51.000000 #
#    27.                        "Idmn" 49.000000 #
#    28.                "JointAverage" 49.000000 #
#    29.           "DifferenceAverage" 46.000000 #
#    30.                     "Entropy" 44.000000 #
#    31.                      "Median" 41.000000 #
#    32.             "RootMeanSquared" 41.000000 #
#    33.                  "SumSquares" 40.000000 #
#    34.             "InverseVariance" 38.000000 #
#    35.                  "SumAverage" 38.000000 #
#    36.                 "Correlation" 33.000000
#    37.                        "Imc2" 33.000000
#    38.          "MaximumProbability" 27.000000
#    39.                "90Percentile" 20.000000
#    40.                  "Uniformity" 20.000000
#    41.                     "Maximum" 18.000000
#    42.                         "MCC" 16.000000
#
# Variable Importance: SUM_SCORE:
#     1.                 "JointEnergy" 952.863503 ################
#     2.           "ClusterProminence"  0.000001
#     3.                         "Idm"  0.000001
#     4.          "InterquartileRange"  0.000001
#     5.                 "TotalEnergy"  0.000001
#     6.                      "Energy"  0.000000
#     7.                    "Skewness"  0.000000
#     8.                        "Mean"  0.000000
#     9.             "RootMeanSquared"  0.000000
#    10.                     "Minimum"  0.000000
#    11. "RobustMeanAbsoluteDeviation"  0.000000
#    12.                "JointEntropy"  0.000000
#    13.                "10Percentile"  0.000000
#    14.                 "Correlation"  0.000000
#    15.       "MeanAbsoluteDeviation"  0.000000
#    16.             "ClusterTendency"  0.000000
#    17.             "Autocorrelation"  0.000000
#    18.          "DifferenceVariance"  0.000000
#    19.                    "Kurtosis"  0.000000
#    20.                  "SumAverage"  0.000000
#    21.                "ClusterShade"  0.000000
#    22.                "JointAverage"  0.000000
#    23.                        "Imc1"  0.000000
#    24.                    "Variance"  0.000000
#    25.          "MaximumProbability"  0.000000
#    26.                       "Range"  0.000000
#    27.                  "SumEntropy"  0.000000
#    28.                          "Id"  0.000000
#    29.                     "Entropy"  0.000000
#    30.                      "Median"  0.000000
#    31.                  "SumSquares"  0.000000
#    32.                "90Percentile"  0.000000
#    33.                        "Imc2"  0.000000
#    34.                    "Contrast"  0.000000
#    35.           "DifferenceAverage"  0.000000
#    36.                         "Idn"  0.000000
#    37.                        "Idmn"  0.000000
#    38.                         "MCC"  0.000000
#    39.             "InverseVariance"  0.000000
#    40.                  "Uniformity"  0.000000
#    41.           "DifferenceEntropy"  0.000000
#    42.                     "Maximum"  0.000000
#
#
#
# Loss: BINOMIAL_LOG_LIKELIHOOD
# Validation loss value: 2.25811e-06
# Number of trees per iteration: 1
# Node format: NOT_SET
# Number of trees: 300
# Total number of nodes: 8912
#
# Number of nodes by tree:
# Count: 300 Average: 29.7067 StdDev: 12.1855
# Min: 9 Max: 53 Ignored: 0
# ----------------------------------------------
# [  9, 11)  4   1.33%   1.33%
# [ 11, 13) 15   5.00%   6.33% ##
# [ 13, 15) 26   8.67%  15.00% ###
# [ 15, 18) 32  10.67%  25.67% ####
# [ 18, 20)  6   2.00%  27.67% #
# [ 20, 22)  2   0.67%  28.33%
# [ 22, 24)  0   0.00%  28.33%
# [ 24, 27)  0   0.00%  28.33%
# [ 27, 29)  2   0.67%  29.00%
# [ 29, 31) 35  11.67%  40.67% ####
# [ 31, 33) 88  29.33%  70.00% ##########
# [ 33, 36) 32  10.67%  80.67% ####
# [ 36, 38)  0   0.00%  80.67%
# [ 38, 40)  0   0.00%  80.67%
# [ 40, 42)  6   2.00%  82.67% #
# [ 42, 45)  0   0.00%  82.67%
# [ 45, 47)  3   1.00%  83.67%
# [ 47, 49)  6   2.00%  85.67% #
# [ 49, 51)  6   2.00%  87.67% #
# [ 51, 53] 37  12.33% 100.00% ####
#
# Depth by leafs:
# Count: 4606 Average: 4.22536 StdDev: 0.854108
# Min: 1 Max: 5 Ignored: 0
# ----------------------------------------------
# [ 1, 2)    4   0.09%   0.09%
# [ 2, 3)  128   2.78%   2.87% #
# [ 3, 4)  870  18.89%  21.75% ####
# [ 4, 5) 1428  31.00%  52.76% #######
# [ 5, 5] 2176  47.24% 100.00% ##########
#
# Number of training obs by leaf:
# Count: 4606 Average: 46.1789 StdDev: 91.7217
# Min: 5 Max: 444 Ignored: 0
# ----------------------------------------------
# [   5,  27) 3480  75.55%  75.55% ##########
# [  27,  49)  268   5.82%  81.37% #
# [  49,  71)  150   3.26%  84.63%
# [  71,  93)   64   1.39%  86.02%
# [  93, 115)   28   0.61%  86.63%
# [ 115, 137)   50   1.09%  87.71%
# [ 137, 159)   19   0.41%  88.12%
# [ 159, 181)   36   0.78%  88.91%
# [ 181, 203)   72   1.56%  90.47%
# [ 203, 225)   70   1.52%  91.99%
# [ 225, 247)   90   1.95%  93.94%
# [ 247, 269)   33   0.72%  94.66%
# [ 269, 291)   33   0.72%  95.38%
# [ 291, 313)   45   0.98%  96.35%
# [ 313, 335)   19   0.41%  96.77%
# [ 335, 357)   61   1.32%  98.09%
# [ 357, 379)   10   0.22%  98.31%
# [ 379, 401)   22   0.48%  98.78%
# [ 401, 423)   36   0.78%  99.57%
# [ 423, 444]   20   0.43% 100.00%
#
# Attribute in nodes:
# 	355 : Idm [NUMERICAL]
# 	344 : Skewness [NUMERICAL]
# 	307 : Imc1 [NUMERICAL]
# 	285 : JointEnergy [NUMERICAL]
# 	239 : Minimum [NUMERICAL]
# 	238 : ClusterProminence [NUMERICAL]
# 	218 : Mean [NUMERICAL]
# 	208 : ClusterShade [NUMERICAL]
# 	188 : DifferenceVariance [NUMERICAL]
# 	152 : RobustMeanAbsoluteDeviation [NUMERICAL]
# 	125 : MeanAbsoluteDeviation [NUMERICAL]
# 	114 : 10Percentile [NUMERICAL]
# 	111 : Id [NUMERICAL]
# 	90 : SumEntropy [NUMERICAL]
# 	86 : Range [NUMERICAL]
# 	85 : ClusterTendency [NUMERICAL]
# 	76 : DifferenceEntropy [NUMERICAL]
# 	66 : Kurtosis [NUMERICAL]
# 	65 : TotalEnergy [NUMERICAL]
# 	64 : Variance [NUMERICAL]
# 	61 : Contrast [NUMERICAL]
# 	59 : InterquartileRange [NUMERICAL]
# 	57 : Idn [NUMERICAL]
# 	57 : Energy [NUMERICAL]
# 	52 : Autocorrelation [NUMERICAL]
# 	51 : JointEntropy [NUMERICAL]
# 	49 : JointAverage [NUMERICAL]
# 	49 : Idmn [NUMERICAL]
# 	46 : DifferenceAverage [NUMERICAL]
# 	44 : Entropy [NUMERICAL]
# 	41 : RootMeanSquared [NUMERICAL]
# 	41 : Median [NUMERICAL]
# 	40 : SumSquares [NUMERICAL]
# 	38 : SumAverage [NUMERICAL]
# 	38 : InverseVariance [NUMERICAL]
# 	33 : Imc2 [NUMERICAL]
# 	33 : Correlation [NUMERICAL]
# 	27 : MaximumProbability [NUMERICAL]
# 	20 : Uniformity [NUMERICAL]
# 	20 : 90Percentile [NUMERICAL]
# 	18 : Maximum [NUMERICAL]
# 	16 : MCC [NUMERICAL]
#
# Attribute in nodes with depth <= 0:
# 	161 : ClusterProminence [NUMERICAL]
# 	107 : JointEnergy [NUMERICAL]
# 	15 : TotalEnergy [NUMERICAL]
# 	13 : Energy [NUMERICAL]
# 	4 : InterquartileRange [NUMERICAL]
#
# Attribute in nodes with depth <= 1:
# 	254 : Idm [NUMERICAL]
# 	219 : JointEnergy [NUMERICAL]
# 	195 : ClusterProminence [NUMERICAL]
# 	63 : Id [NUMERICAL]
# 	28 : Skewness [NUMERICAL]
# 	22 : TotalEnergy [NUMERICAL]
# 	17 : Energy [NUMERICAL]
# 	14 : SumEntropy [NUMERICAL]
# 	10 : ClusterTendency [NUMERICAL]
# 	8 : InterquartileRange [NUMERICAL]
# 	7 : MaximumProbability [NUMERICAL]
# 	6 : ClusterShade [NUMERICAL]
# 	5 : Autocorrelation [NUMERICAL]
# 	4 : RootMeanSquared [NUMERICAL]
# 	4 : Minimum [NUMERICAL]
# 	4 : Imc2 [NUMERICAL]
# 	4 : Contrast [NUMERICAL]
# 	3 : SumSquares [NUMERICAL]
# 	3 : Mean [NUMERICAL]
# 	3 : MCC [NUMERICAL]
# 	3 : JointEntropy [NUMERICAL]
# 	3 : Idmn [NUMERICAL]
# 	3 : DifferenceEntropy [NUMERICAL]
# 	3 : DifferenceAverage [NUMERICAL]
# 	3 : Correlation [NUMERICAL]
# 	2 : JointAverage [NUMERICAL]
# 	2 : InverseVariance [NUMERICAL]
# 	1 : SumAverage [NUMERICAL]
# 	1 : Imc1 [NUMERICAL]
# 	1 : Idn [NUMERICAL]
# 	1 : DifferenceVariance [NUMERICAL]
#
# Attribute in nodes with depth <= 2:
# 	316 : Idm [NUMERICAL]
# 	226 : JointEnergy [NUMERICAL]
# 	224 : ClusterProminence [NUMERICAL]
# 	218 : Skewness [NUMERICAL]
# 	168 : Imc1 [NUMERICAL]
# 	146 : ClusterShade [NUMERICAL]
# 	89 : Id [NUMERICAL]
# 	55 : ClusterTendency [NUMERICAL]
# 	46 : Minimum [NUMERICAL]
# 	36 : DifferenceEntropy [NUMERICAL]
# 	34 : SumEntropy [NUMERICAL]
# 	31 : TotalEnergy [NUMERICAL]
# 	27 : RobustMeanAbsoluteDeviation [NUMERICAL]
# 	27 : Energy [NUMERICAL]
# 	22 : JointAverage [NUMERICAL]
# 	22 : Idmn [NUMERICAL]
# 	22 : Contrast [NUMERICAL]
# 	19 : Imc2 [NUMERICAL]
# 	19 : Correlation [NUMERICAL]
# 	18 : MaximumProbability [NUMERICAL]
# 	18 : Idn [NUMERICAL]
# 	18 : Autocorrelation [NUMERICAL]
# 	15 : SumSquares [NUMERICAL]
# 	15 : InverseVariance [NUMERICAL]
# 	13 : Mean [NUMERICAL]
# 	12 : JointEntropy [NUMERICAL]
# 	10 : InterquartileRange [NUMERICAL]
# 	10 : DifferenceVariance [NUMERICAL]
# 	10 : DifferenceAverage [NUMERICAL]
# 	9 : SumAverage [NUMERICAL]
# 	8 : RootMeanSquared [NUMERICAL]
# 	8 : Range [NUMERICAL]
# 	7 : MeanAbsoluteDeviation [NUMERICAL]
# 	7 : MCC [NUMERICAL]
# 	7 : 90Percentile [NUMERICAL]
# 	7 : 10Percentile [NUMERICAL]
# 	6 : Maximum [NUMERICAL]
# 	5 : Kurtosis [NUMERICAL]
# 	4 : Entropy [NUMERICAL]
# 	3 : Uniformity [NUMERICAL]
# 	3 : Median [NUMERICAL]
#
# Attribute in nodes with depth <= 3:
# 	344 : Idm [NUMERICAL]
# 	276 : Imc1 [NUMERICAL]
# 	236 : ClusterProminence [NUMERICAL]
# 	233 : Skewness [NUMERICAL]
# 	232 : JointEnergy [NUMERICAL]
# 	180 : ClusterShade [NUMERICAL]
# 	147 : Mean [NUMERICAL]
# 	146 : DifferenceVariance [NUMERICAL]
# 	114 : MeanAbsoluteDeviation [NUMERICAL]
# 	108 : Id [NUMERICAL]
# 	102 : Minimum [NUMERICAL]
# 	96 : RobustMeanAbsoluteDeviation [NUMERICAL]
# 	83 : SumEntropy [NUMERICAL]
# 	80 : ClusterTendency [NUMERICAL]
# 	72 : DifferenceEntropy [NUMERICAL]
# 	54 : 10Percentile [NUMERICAL]
# 	50 : JointEntropy [NUMERICAL]
# 	50 : Idn [NUMERICAL]
# 	49 : Contrast [NUMERICAL]
# 	47 : TotalEnergy [NUMERICAL]
# 	43 : Energy [NUMERICAL]
# 	41 : Idmn [NUMERICAL]
# 	40 : DifferenceAverage [NUMERICAL]
# 	36 : Variance [NUMERICAL]
# 	36 : SumSquares [NUMERICAL]
# 	36 : JointAverage [NUMERICAL]
# 	33 : Autocorrelation [NUMERICAL]
# 	28 : InverseVariance [NUMERICAL]
# 	24 : MaximumProbability [NUMERICAL]
# 	21 : Kurtosis [NUMERICAL]
# 	21 : Correlation [NUMERICAL]
# 	20 : InterquartileRange [NUMERICAL]
# 	20 : Imc2 [NUMERICAL]
# 	18 : SumAverage [NUMERICAL]
# 	17 : RootMeanSquared [NUMERICAL]
# 	17 : Maximum [NUMERICAL]
# 	15 : Median [NUMERICAL]
# 	14 : Entropy [NUMERICAL]
# 	12 : Range [NUMERICAL]
# 	10 : Uniformity [NUMERICAL]
# 	10 : 90Percentile [NUMERICAL]
# 	7 : MCC [NUMERICAL]
#
# Attribute in nodes with depth <= 5:
# 	355 : Idm [NUMERICAL]
# 	344 : Skewness [NUMERICAL]
# 	307 : Imc1 [NUMERICAL]
# 	285 : JointEnergy [NUMERICAL]
# 	239 : Minimum [NUMERICAL]
# 	238 : ClusterProminence [NUMERICAL]
# 	218 : Mean [NUMERICAL]
# 	208 : ClusterShade [NUMERICAL]
# 	188 : DifferenceVariance [NUMERICAL]
# 	152 : RobustMeanAbsoluteDeviation [NUMERICAL]
# 	125 : MeanAbsoluteDeviation [NUMERICAL]
# 	114 : 10Percentile [NUMERICAL]
# 	111 : Id [NUMERICAL]
# 	90 : SumEntropy [NUMERICAL]
# 	86 : Range [NUMERICAL]
# 	85 : ClusterTendency [NUMERICAL]
# 	76 : DifferenceEntropy [NUMERICAL]
# 	66 : Kurtosis [NUMERICAL]
# 	65 : TotalEnergy [NUMERICAL]
# 	64 : Variance [NUMERICAL]
# 	61 : Contrast [NUMERICAL]
# 	59 : InterquartileRange [NUMERICAL]
# 	57 : Idn [NUMERICAL]
# 	57 : Energy [NUMERICAL]
# 	52 : Autocorrelation [NUMERICAL]
# 	51 : JointEntropy [NUMERICAL]
# 	49 : JointAverage [NUMERICAL]
# 	49 : Idmn [NUMERICAL]
# 	46 : DifferenceAverage [NUMERICAL]
# 	44 : Entropy [NUMERICAL]
# 	41 : RootMeanSquared [NUMERICAL]
# 	41 : Median [NUMERICAL]
# 	40 : SumSquares [NUMERICAL]
# 	38 : SumAverage [NUMERICAL]
# 	38 : InverseVariance [NUMERICAL]
# 	33 : Imc2 [NUMERICAL]
# 	33 : Correlation [NUMERICAL]
# 	27 : MaximumProbability [NUMERICAL]
# 	20 : Uniformity [NUMERICAL]
# 	20 : 90Percentile [NUMERICAL]
# 	18 : Maximum [NUMERICAL]
# 	16 : MCC [NUMERICAL]
#
# Condition type in nodes:
# 	4306 : HigherCondition
# Condition type in nodes with depth <= 0:
# 	300 : HigherCondition
# Condition type in nodes with depth <= 1:
# 	896 : HigherCondition
# Condition type in nodes with depth <= 2:
# 	1960 : HigherCondition
# Condition type in nodes with depth <= 3:
# 	3218 : HigherCondition
# Condition type in nodes with depth <= 5:
# 	4306 : HigherCondition
#
# Training logs:
# Number of iteration to final model: 300
# 	Iter:1 train-loss:1.196179 valid-loss:1.198007  train-accuracy:1.000000 valid-accuracy:1.000000
# 	Iter:2 train-loss:1.040566 valid-loss:1.042078  train-accuracy:1.000000 valid-accuracy:1.000000
# 	Iter:3 train-loss:0.910804 valid-loss:0.912075  train-accuracy:1.000000 valid-accuracy:1.000000
# 	Iter:4 train-loss:0.801120 valid-loss:0.802200  train-accuracy:1.000000 valid-accuracy:1.000000
# 	Iter:5 train-loss:0.707425 valid-loss:0.708352  train-accuracy:1.000000 valid-accuracy:1.000000
# 	Iter:6 train-loss:0.626714 valid-loss:0.627516  train-accuracy:1.000000 valid-accuracy:1.000000
# 	Iter:16 train-loss:0.206063 valid-loss:0.206296  train-accuracy:1.000000 valid-accuracy:1.000000
# 	Iter:26 train-loss:0.073108 valid-loss:0.073188  train-accuracy:1.000000 valid-accuracy:1.000000
# 	Iter:36 train-loss:0.026553 valid-loss:0.026582  train-accuracy:1.000000 valid-accuracy:1.000000
# 	Iter:46 train-loss:0.009723 valid-loss:0.009734  train-accuracy:1.000000 valid-accuracy:1.000000
# 	Iter:56 train-loss:0.003571 valid-loss:0.003575  train-accuracy:1.000000 valid-accuracy:1.000000
# 	Iter:66 train-loss:0.001313 valid-loss:0.001314  train-accuracy:1.000000 valid-accuracy:1.000000
# 	Iter:76 train-loss:0.000483 valid-loss:0.000484  train-accuracy:1.000000 valid-accuracy:1.000000
# 	Iter:86 train-loss:0.000178 valid-loss:0.000178  train-accuracy:1.000000 valid-accuracy:1.000000
# 	Iter:96 train-loss:0.000073 valid-loss:0.000074  train-accuracy:1.000000 valid-accuracy:1.000000
# 	Iter:106 train-loss:0.000035 valid-loss:0.000035  train-accuracy:1.000000 valid-accuracy:1.000000
# 	Iter:116 train-loss:0.000019 valid-loss:0.000019  train-accuracy:1.000000 valid-accuracy:1.000000
# 	Iter:126 train-loss:0.000013 valid-loss:0.000013  train-accuracy:1.000000 valid-accuracy:1.000000
# 	Iter:136 train-loss:0.000011 valid-loss:0.000011  train-accuracy:1.000000 valid-accuracy:1.000000
# 	Iter:146 train-loss:0.000009 valid-loss:0.000009  train-accuracy:1.000000 valid-accuracy:1.000000
# 	Iter:156 train-loss:0.000006 valid-loss:0.000007  train-accuracy:1.000000 valid-accuracy:1.000000
# 	Iter:166 train-loss:0.000006 valid-loss:0.000006  train-accuracy:1.000000 valid-accuracy:1.000000
# 	Iter:176 train-loss:0.000005 valid-loss:0.000005  train-accuracy:1.000000 valid-accuracy:1.000000
# 	Iter:186 train-loss:0.000004 valid-loss:0.000005  train-accuracy:1.000000 valid-accuracy:1.000000
# 	Iter:196 train-loss:0.000004 valid-loss:0.000004  train-accuracy:1.000000 valid-accuracy:1.000000
# 	Iter:206 train-loss:0.000004 valid-loss:0.000004  train-accuracy:1.000000 valid-accuracy:1.000000
# 	Iter:216 train-loss:0.000003 valid-loss:0.000004  train-accuracy:1.000000 valid-accuracy:1.000000
# 	Iter:226 train-loss:0.000003 valid-loss:0.000003  train-accuracy:1.000000 valid-accuracy:1.000000
# 	Iter:236 train-loss:0.000003 valid-loss:0.000003  train-accuracy:1.000000 valid-accuracy:1.000000
# 	Iter:246 train-loss:0.000003 valid-loss:0.000003  train-accuracy:1.000000 valid-accuracy:1.000000
# 	Iter:256 train-loss:0.000003 valid-loss:0.000003  train-accuracy:1.000000 valid-accuracy:1.000000
# 	Iter:266 train-loss:0.000002 valid-loss:0.000003  train-accuracy:1.000000 valid-accuracy:1.000000
# 	Iter:276 train-loss:0.000002 valid-loss:0.000003  train-accuracy:1.000000 valid-accuracy:1.000000
# 	Iter:286 train-loss:0.000002 valid-loss:0.000002  train-accuracy:1.000000 valid-accuracy:1.000000
# 	Iter:296 train-loss:0.000002 valid-loss:0.000002  train-accuracy:1.000000 valid-accuracy:1.000000

# %%
# Model features
model.make_inspector().features()
# Out:
# ["10Percentile" (1; #0),
#  "90Percentile" (1; #1),
#  "Autocorrelation" (1; #2),
#  "ClusterProminence" (1; #3),
#  "ClusterShade" (1; #4),
#  "ClusterTendency" (1; #5),
#  "Contrast" (1; #6),
#  "Correlation" (1; #7),
#  "DifferenceAverage" (1; #8),
#  "DifferenceEntropy" (1; #9),
#  "DifferenceVariance" (1; #10),
#  "Energy" (1; #11),
#  "Entropy" (1; #12),
#  "Id" (1; #13),
#  "Idm" (1; #14),
#  "Idmn" (1; #15),
#  "Idn" (1; #16),
#  "Imc1" (1; #17),
#  "Imc2" (1; #18),
#  "InterquartileRange" (1; #19),
#  "InverseVariance" (1; #20),
#  "JointAverage" (1; #21),
#  "JointEnergy" (1; #22),
#  "JointEntropy" (1; #23),
#  "Kurtosis" (1; #24),
#  "MCC" (1; #25),
#  "Maximum" (1; #26),
#  "MaximumProbability" (1; #27),
#  "Mean" (1; #28),
#  "MeanAbsoluteDeviation" (1; #29),
#  "Median" (1; #30),
#  "Minimum" (1; #31),
#  "Range" (1; #32),
#  "RobustMeanAbsoluteDeviation" (1; #33),
#  "RootMeanSquared" (1; #34),
#  "Skewness" (1; #35),
#  "SumAverage" (1; #36),
#  "SumEntropy" (1; #37),
#  "SumSquares" (1; #38),
#  "TotalEnergy" (1; #39),
#  "Uniformity" (1; #40),
#  "Variance" (1; #41)]

# %%
# Feature importance
model.make_inspector().variable_importances()
# Out:
# {'INV_MEAN_MIN_DEPTH': [("ClusterProminence" (1; #3), 0.40304216010790034),
#   ("Idm" (1; #14), 0.30571368825465206),
#   ("JointEnergy" (1; #22), 0.2665879559668214),
#   ("Skewness" (1; #35), 0.24858567056488126),
#   ("TotalEnergy" (1; #39), 0.21515018386031984),
#   ("ClusterShade" (1; #4), 0.2127884539624102),
#   ("Energy" (1; #11), 0.21278844351542778),
#   ("Minimum" (1; #31), 0.21021338380428606),
#   ("Mean" (1; #28), 0.209510842639558),
#   ("Id" (1; #13), 0.20903234051550393),
#   ("Imc1" (1; #17), 0.20872796677831396),
#   ("MeanAbsoluteDeviation" (1; #29), 0.2082756144922026),
#   ("RobustMeanAbsoluteDeviation" (1; #33), 0.20702674306823515),
#   ("ClusterTendency" (1; #5), 0.20451600838775805),
#   ("InterquartileRange" (1; #19), 0.204285031170013),
#   ("DifferenceVariance" (1; #10), 0.20382296661312954),
#   ("SumEntropy" (1; #37), 0.2036788970552897),
#   ("10Percentile" (1; #0), 0.20357467787150862),
#   ("Variance" (1; #41), 0.20305571534078648),
#   ("Correlation" (1; #7), 0.2029729010073541),
#   ("RootMeanSquared" (1; #34), 0.2026400846141757),
#   ("Kurtosis" (1; #24), 0.20246195486478927),
#   ("DifferenceEntropy" (1; #9), 0.2024071820081898),
#   ("Range" (1; #32), 0.2023432228477271),
#   ("JointEntropy" (1; #23), 0.20208048704151252),
#   ("Idn" (1; #16), 0.20205732192061185),
#   ("Autocorrelation" (1; #2), 0.20203350196198894),
#   ("MaximumProbability" (1; #27), 0.2020140817032606),
#   ("Contrast" (1; #6), 0.20192135301457081),
#   ("JointAverage" (1; #21), 0.2018184462359082),
#   ("InverseVariance" (1; #20), 0.2017884817755631),
#   ("Median" (1; #30), 0.20177425417639394),
#   ("DifferenceAverage" (1; #8), 0.20171185875288214),
#   ("Idmn" (1; #15), 0.2017075146072993),
#   ("SumSquares" (1; #38), 0.20155631825425155),
#   ("Entropy" (1; #12), 0.2015281398776901),
#   ("90Percentile" (1; #1), 0.20147721560711612),
#   ("Imc2" (1; #18), 0.20147225804190966),
#   ("SumAverage" (1; #36), 0.20131565196069184),
#   ("Maximum" (1; #26), 0.2013129032369266),
#   ("MCC" (1; #25), 0.20117247177803513),
#   ("Uniformity" (1; #40), 0.20104663039525875)],
#  'NUM_AS_ROOT': [("ClusterProminence" (1; #3), 161.0),
#   ("JointEnergy" (1; #22), 107.0),
#   ("TotalEnergy" (1; #39), 15.0),
#   ("Energy" (1; #11), 13.0),
#   ("InterquartileRange" (1; #19), 4.0)],
#  'SUM_SCORE': [("JointEnergy" (1; #22), 952.863502612081),
#   ("ClusterProminence" (1; #3), 1.337314904846735e-06),
#   ("Idm" (1; #14), 9.918492139084105e-07),
#   ("InterquartileRange" (1; #19), 7.075988157344085e-07),
#   ("TotalEnergy" (1; #39), 6.253336454292554e-07),
#   ("Energy" (1; #11), 4.4101747627448157e-07),
#   ("Skewness" (1; #35), 3.7891869746230856e-07),
#   ("Mean" (1; #28), 1.542263935961228e-07),
#   ("RootMeanSquared" (1; #34), 1.3552943892338415e-07),
#   ("Minimum" (1; #31), 1.1788502131032807e-07),
#   ("RobustMeanAbsoluteDeviation" (1; #33), 9.155528404439628e-08),
#   ("JointEntropy" (1; #23), 6.910313488128617e-08),
#   ("10Percentile" (1; #0), 4.775252313677213e-08),
#   ("Correlation" (1; #7), 4.417927910158693e-08),
#   ("MeanAbsoluteDeviation" (1; #29), 4.2453111006118935e-08),
#   ("ClusterTendency" (1; #5), 3.1837723987757226e-08),
#   ("Autocorrelation" (1; #2), 1.7222095384075196e-08),
#   ("DifferenceVariance" (1; #10), 1.6451885201370655e-08),
#   ("Kurtosis" (1; #24), 1.5744585878485636e-08),
#   ("SumAverage" (1; #36), 1.474557290989587e-08),
#   ("ClusterShade" (1; #4), 1.3482475724193459e-08),
#   ("JointAverage" (1; #21), 1.1175441065331963e-08),
#   ("Imc1" (1; #17), 8.565731223868934e-09),
#   ("Variance" (1; #41), 6.293075253747334e-09),
#   ("MaximumProbability" (1; #27), 5.853325736185125e-09),
#   ("Range" (1; #32), 4.209767945739311e-09),
#   ("SumEntropy" (1; #37), 4.068789654784682e-09),
#   ("Id" (1; #13), 3.663666382221888e-09),
#   ("Entropy" (1; #12), 3.6209929437970806e-09),
#   ("Median" (1; #30), 3.5295007822806044e-09),
#   ("SumSquares" (1; #38), 2.9231648593640704e-09),
#   ("90Percentile" (1; #1), 2.797266597416397e-09),
#   ("Imc2" (1; #18), 1.6315915391537452e-09),
#   ("Contrast" (1; #6), 1.4955541773135203e-09),
#   ("DifferenceAverage" (1; #8), 1.4770260440550356e-09),
#   ("Idn" (1; #16), 1.4556868733170421e-09),
#   ("Idmn" (1; #15), 1.411356953560979e-09),
#   ("MCC" (1; #25), 1.2429026859198122e-09),
#   ("InverseVariance" (1; #20), 1.0074018241150441e-09),
#   ("Uniformity" (1; #40), 8.949589951319109e-10),
#   ("DifferenceEntropy" (1; #9), 4.4400928408689897e-10),
#   ("Maximum" (1; #26), 3.879414263502029e-10)],
#  'NUM_NODES': [("Idm" (1; #14), 355.0),
#   ("Skewness" (1; #35), 344.0),
#   ("Imc1" (1; #17), 307.0),
#   ("JointEnergy" (1; #22), 285.0),
#   ("Minimum" (1; #31), 239.0),
#   ("ClusterProminence" (1; #3), 238.0),
#   ("Mean" (1; #28), 218.0),
#   ("ClusterShade" (1; #4), 208.0),
#   ("DifferenceVariance" (1; #10), 188.0),
#   ("RobustMeanAbsoluteDeviation" (1; #33), 152.0),
#   ("MeanAbsoluteDeviation" (1; #29), 125.0),
#   ("10Percentile" (1; #0), 114.0),
#   ("Id" (1; #13), 111.0),
#   ("SumEntropy" (1; #37), 90.0),
#   ("Range" (1; #32), 86.0),
#   ("ClusterTendency" (1; #5), 85.0),
#   ("DifferenceEntropy" (1; #9), 76.0),
#   ("Kurtosis" (1; #24), 66.0),
#   ("TotalEnergy" (1; #39), 65.0),
#   ("Variance" (1; #41), 64.0),
#   ("Contrast" (1; #6), 61.0),
#   ("InterquartileRange" (1; #19), 59.0),
#   ("Energy" (1; #11), 57.0),
#   ("Idn" (1; #16), 57.0),
#   ("Autocorrelation" (1; #2), 52.0),
#   ("JointEntropy" (1; #23), 51.0),
#   ("Idmn" (1; #15), 49.0),
#   ("JointAverage" (1; #21), 49.0),
#   ("DifferenceAverage" (1; #8), 46.0),
#   ("Entropy" (1; #12), 44.0),
#   ("Median" (1; #30), 41.0),
#   ("RootMeanSquared" (1; #34), 41.0),
#   ("SumSquares" (1; #38), 40.0),
#   ("InverseVariance" (1; #20), 38.0),
#   ("SumAverage" (1; #36), 38.0),
#   ("Correlation" (1; #7), 33.0),
#   ("Imc2" (1; #18), 33.0),
#   ("MaximumProbability" (1; #27), 27.0),
#   ("90Percentile" (1; #1), 20.0),
#   ("Uniformity" (1; #40), 20.0),
#   ("Maximum" (1; #26), 18.0),
#   ("MCC" (1; #25), 16.0)]}

# %%
# Model self evaluation
model.make_inspector().evaluation()
# Out:
# Evaluation(num_examples=None, accuracy=1.0, loss=2.258111180708511e-06, rmse=None, ndcg=None, aucs=None, auuc=None, qini=None)

# %%
logs = model.make_inspector().training_logs()

plt.figure(figsize=(12, 4))
plt.subplot(1, 2, 1)
plt.plot([log.num_trees for log in logs], [log.evaluation.accuracy for log in logs])
plt.xlabel("Number of trees")
plt.ylabel("Accuracy (out-of-bag)")
plt.subplot(1, 2, 2)
plt.plot([log.num_trees for log in logs], [log.evaluation.loss for log in logs])
plt.xlabel("Number of trees")
plt.ylabel("Logloss (out-of-bag)")
plt.show()

# %% [markdown]
# Calculate the score of our hold-out validation dataset

# %%
predictions = model.predict(val_ds)
y_true      = validation_data["label"]

from sklearn.metrics import roc_auc_score
ROC_AUC = roc_auc_score(y_true, predictions)
print("The ROC AUC score is %.5f" % ROC_AUC )
# Out:
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 76ms/step
# The ROC AUC score is 1.00000

# %%
# Compute binary classification metrics with sklearn
import numpy as np
from sklearn.metrics import (
    accuracy_score,
    precision_score,
    recall_score,
    f1_score,
    roc_auc_score,
    average_precision_score,
    confusion_matrix,
    classification_report,
    matthews_corrcoef,
    log_loss,
    brier_score_loss,
)

# Get predictions (probabilities or class labels)
preds = model.predict(test_ds)
# If model outputs probabilities, convert to labels by threshold 0.5
if preds.ndim == 2:
    # For TFDF classification, preds may be class probabilities with shape (N, 2)
    if preds.shape[1] == 2:
        pos_probs = preds[:, 1]
    else:
        # If single-probability column (positive class)
        pos_probs = preds[:, -1]
    y_pred = (pos_probs >= 0.5).astype(int)
else:
    # Already class labels
    y_pred = preds.astype(int)
    pos_probs = None

# Ground truth labels (must be 0/1 integers)
y_true = test_data["label"].astype(int).to_numpy()

# Core metrics
metrics = {}
metrics["accuracy"] = accuracy_score(y_true, y_pred)
metrics["precision"] = precision_score(y_true, y_pred, zero_division=0)
metrics["recall"] = recall_score(y_true, y_pred, zero_division=0)
metrics["f1"] = f1_score(y_true, y_pred, zero_division=0)
metrics["mcc"] = matthews_corrcoef(y_true, y_pred)

# Probabilistic metrics (only if we have probabilities)
if pos_probs is not None:
    metrics["roc_auc"] = roc_auc_score(y_true, pos_probs)
    metrics["pr_auc"] = average_precision_score(y_true, pos_probs)
    metrics["log_loss"] = log_loss(y_true, pos_probs, labels=[0,1])
    metrics["brier_score"] = brier_score_loss(y_true, pos_probs)

# Confusion matrix and detailed report
cm = confusion_matrix(y_true, y_pred, labels=[0,1])
report = classification_report(y_true, y_pred, digits=4)

print("Sklearn binary metrics:")
for k, v in metrics.items():
    print(f"{k}: {v:.4f}")
print("\nConfusion matrix:\n", cm)
print("\nClassification report:\n", report)
# Out:
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 80ms/step
# Sklearn binary metrics:
# accuracy: 1.0000
# precision: 1.0000
# recall: 1.0000
# f1: 1.0000
# mcc: 1.0000
# roc_auc: 1.0000
# pr_auc: 1.0000
# log_loss: 0.0000
# brier_score: 0.0000
#
# Confusion matrix:
#  [[ 95   0]
#  [  0 127]]
#
# Classification report:
#                precision    recall  f1-score   support
#
#            0     1.0000    1.0000    1.0000        95
#            1     1.0000    1.0000    1.0000       127
#
#     accuracy                         1.0000       222
#    macro avg     1.0000    1.0000    1.0000       222
# weighted avg     1.0000    1.0000    1.0000       222
