# %%
# Import packages and modules
import numpy  as np
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow_decision_forests as tfdf

from sklearn.model_selection import train_test_split
# Out:
# 2026-07-04 08:46:26.123400: I tensorflow/core/util/port.cc:113] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2026-07-04 08:46:26.167018: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2026-07-04 08:46:30.772933: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
# Check the version of TensorFlow Decision Forests
print("Found TensorFlow Decision Forests v" + tfdf.__version__)
# Out:
# Found TensorFlow Decision Forests v1.9.1

# %%
datasetPath = 'dataset/firstorder/kernel5-radius5/dataset.csv'

# %%
# Parameters
datasetPath = "dataset/glrlm/kernel5-radius5/100.dataset.csv"

# %%
# train/validation/test = 70/10/20
dataset = pd.read_csv(datasetPath)

train_data, temp_data = train_test_split(dataset, test_size=0.3, random_state=42)
validation_data, test_data = train_test_split(temp_data, test_size=2/3, random_state=42)

# %%
from sklearn.utils.class_weight import compute_class_weight

# tinh class weight tren tap train
classes = np.array([0, 1])
weights = compute_class_weight(class_weight="balanced", classes=classes, y=train_data["label"])
class_weight = {0: weights[0], 1: weights[1]}

# gan sample_weight cho tung dong
train_data["sample_weight"] = train_data["label"].map(class_weight)
validation_data["sample_weight"] = validation_data["label"].map(class_weight)
test_data["sample_weight"] = test_data["label"].map(class_weight)

# Convert the dataset into a TensorFlow dataset.
train_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    train_data, label="label", weight="sample_weight"
)         
val_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    validation_data, label="label", weight="sample_weight"
)
test_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    test_data, label="label", weight="sample_weight"
)
# Out:
# 2026-07-04 08:46:42.848994: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:984] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2026-07-04 08:46:42.850588: W tensorflow/core/common_runtime/gpu/gpu_device.cc:2251] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...

# %%
import keras

# %%
# %%time

# Train a Gradient Boosted Trees model.
model = tfdf.keras.GradientBoostedTreesModel()

# Add evaluation metrics
model.compile(
    metrics=["accuracy"]
)
model.fit(x=train_ds)

# # Train a Gradient Boosted Trees model.
# model = tfdf.keras.GradientBoostedTreesModel(num_trees=1500)
# model.fit(train_ds)
# Out:
# Use /tmp/tmpc_iexbgq as temporary training directory
# Reading training dataset...
# [WARNING 26-07-04 08:46:42.9921 UTC gradient_boosted_trees.cc:1840] "goss_alpha" set but "sampling_method" not equal to "GOSS".
# [WARNING 26-07-04 08:46:42.9922 UTC gradient_boosted_trees.cc:1851] "goss_beta" set but "sampling_method" not equal to "GOSS".
# [WARNING 26-07-04 08:46:42.9922 UTC gradient_boosted_trees.cc:1865] "selective_gradient_boosting_ratio" set but "sampling_method" not equal to "SELGB".
# Training dataset read in 0:00:02.756343. Found 78790 examples.
# Training model...
# Model trained in 0:00:13.304035
# Compiling model...
# [INFO 26-07-04 08:46:59.0722 UTC kernel.cc:1233] Loading model from path /tmp/tmpc_iexbgq/model/ with prefix 6a5444ca076b4e36
# [INFO 26-07-04 08:46:59.0804 UTC quick_scorer_extended.cc:911] The binary was compiled without AVX2 support, but your CPU supports it. Enable it for faster model inference.
# [INFO 26-07-04 08:46:59.0811 UTC abstract_model.cc:1362] Engine "GradientBoostedTreesQuickScorerExtended" built
# [INFO 26-07-04 08:46:59.0811 UTC kernel.cc:1061] Use fast generic engine
# Model compiled.
# CPU times: user 1min 29s, sys: 1.81 s, total: 1min 30s
# Wall time: 19.2 s

# %%
# Evaluate the model
evaluate = model.evaluate(val_ds, return_dict=True)
print()

for name, value in evaluate.items():
    print(f"{name}: {value:.4f}")
# Out:
# WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
#  1/12 [=>............................] - ETA: 32s - loss: 0.0000e+00 - accuracy: 0.9330
# 12/12 [==============================] - 3s 4ms/step - loss: 0.0000e+00 - accuracy: 0.9184
# loss: 0.0000
# accuracy: 0.9184

# %%
# Model Summary
model.summary()
# Out:
# Model: "gradient_boosted_trees_model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
# =================================================================
# Total params: 1 (1.00 Byte)
# Trainable params: 0 (0.00 Byte)
# Non-trainable params: 1 (1.00 Byte)
# _________________________________________________________________
# Type: "GRADIENT_BOOSTED_TREES"
# Task: CLASSIFICATION
# Label: "__LABEL"
#
# Input Features (16):
# 	GrayLevelNonUniformity
# 	GrayLevelNonUniformityNormalized
# 	GrayLevelVariance
# 	HighGrayLevelRunEmphasis
# 	LongRunEmphasis
# 	LongRunHighGrayLevelEmphasis
# 	LongRunLowGrayLevelEmphasis
# 	LowGrayLevelRunEmphasis
# 	RunEntropy
# 	RunLengthNonUniformity
# 	RunLengthNonUniformityNormalized
# 	RunPercentage
# 	RunVariance
# 	ShortRunEmphasis
# 	ShortRunHighGrayLevelEmphasis
# 	ShortRunLowGrayLevelEmphasis
#
# Trained with weights
#
# Variable Importance: INV_MEAN_MIN_DEPTH:
#     1.     "LongRunHighGrayLevelEmphasis"  0.276956 ################
#     2.           "GrayLevelNonUniformity"  0.225519 #######
#     3. "RunLengthNonUniformityNormalized"  0.211081 #####
#     4.                       "RunEntropy"  0.201757 ####
#     5.      "LongRunLowGrayLevelEmphasis"  0.199754 ###
#     6.                      "RunVariance"  0.198651 ###
#     7.    "ShortRunHighGrayLevelEmphasis"  0.198340 ###
#     8.     "ShortRunLowGrayLevelEmphasis"  0.195213 ###
#     9.                 "ShortRunEmphasis"  0.193780 ##
#    10.                "GrayLevelVariance"  0.190753 ##
#    11.          "LowGrayLevelRunEmphasis"  0.187121 #
#    12.         "HighGrayLevelRunEmphasis"  0.185095 #
#    13. "GrayLevelNonUniformityNormalized"  0.182205 #
#    14.                  "LongRunEmphasis"  0.179850
#    15.           "RunLengthNonUniformity"  0.178291
#    16.                    "RunPercentage"  0.174842
#
# Variable Importance: NUM_AS_ROOT:
#     1.     "LongRunHighGrayLevelEmphasis" 62.000000 ################
#     2.           "GrayLevelNonUniformity" 25.000000 ######
#     3.      "LongRunLowGrayLevelEmphasis" 16.000000 ###
#     4.                      "RunVariance" 16.000000 ###
#     5. "RunLengthNonUniformityNormalized" 13.000000 ###
#     6.          "LowGrayLevelRunEmphasis"  6.000000 #
#     7.     "ShortRunLowGrayLevelEmphasis"  6.000000 #
#     8.                       "RunEntropy"  5.000000 #
#     9.    "ShortRunHighGrayLevelEmphasis"  5.000000 #
#    10.                "GrayLevelVariance"  4.000000
#    11.         "HighGrayLevelRunEmphasis"  3.000000
#    12. "GrayLevelNonUniformityNormalized"  2.000000
#    13.                  "LongRunEmphasis"  1.000000
#    14.           "RunLengthNonUniformity"  1.000000
#    15.                    "RunPercentage"  1.000000
#    16.                 "ShortRunEmphasis"  1.000000
#
# Variable Importance: NUM_NODES:
#     1.     "LongRunHighGrayLevelEmphasis" 560.000000 ################
#     2.           "GrayLevelNonUniformity" 422.000000 ###########
#     3.                       "RunEntropy" 389.000000 ##########
#     4.    "ShortRunHighGrayLevelEmphasis" 363.000000 #########
#     5.     "ShortRunLowGrayLevelEmphasis" 336.000000 ########
#     6.                "GrayLevelVariance" 329.000000 ########
#     7.      "LongRunLowGrayLevelEmphasis" 318.000000 #######
#     8. "RunLengthNonUniformityNormalized" 248.000000 #####
#     9.          "LowGrayLevelRunEmphasis" 242.000000 #####
#    10.                 "ShortRunEmphasis" 236.000000 #####
#    11.         "HighGrayLevelRunEmphasis" 233.000000 #####
#    12.                      "RunVariance" 228.000000 ####
#    13. "GrayLevelNonUniformityNormalized" 195.000000 ###
#    14.                  "LongRunEmphasis" 118.000000 #
#    15.           "RunLengthNonUniformity" 101.000000
#    16.                    "RunPercentage" 78.000000
#
# Variable Importance: SUM_SCORE:
#     1.     "LongRunHighGrayLevelEmphasis" 32989.165135 ################
#     2.    "ShortRunHighGrayLevelEmphasis" 6213.806191 ##
#     3.           "GrayLevelNonUniformity" 5955.279036 ##
#     4.                       "RunEntropy" 4476.108503 ##
#     5.          "LowGrayLevelRunEmphasis" 4459.137138 ##
#     6.                 "ShortRunEmphasis" 3612.032844 #
#     7.      "LongRunLowGrayLevelEmphasis" 3315.936065 #
#     8.     "ShortRunLowGrayLevelEmphasis" 3223.880790 #
#     9. "RunLengthNonUniformityNormalized" 2682.493761 #
#    10.                      "RunVariance" 2356.167861 #
#    11.         "HighGrayLevelRunEmphasis" 1367.010149
#    12.                "GrayLevelVariance" 1286.471129
#    13. "GrayLevelNonUniformityNormalized" 852.862434
#    14.           "RunLengthNonUniformity" 389.315790
#    15.                  "LongRunEmphasis" 360.452108
#    16.                    "RunPercentage" 268.033846
#
#
#
# Loss: BINOMIAL_LOG_LIKELIHOOD
# Validation loss value: 0.557665
# Number of trees per iteration: 1
# Node format: NOT_SET
# Number of trees: 167
# Total number of nodes: 8959
#
# Number of nodes by tree:
# Count: 167 Average: 53.6467 StdDev: 8.01875
# Min: 25 Max: 63 Ignored: 0
# ----------------------------------------------
# [ 25, 26)  1   0.60%   0.60%
# [ 26, 28)  0   0.00%   0.60%
# [ 28, 30)  0   0.00%   0.60%
# [ 30, 32)  0   0.00%   0.60%
# [ 32, 34)  2   1.20%   1.80% #
# [ 34, 36)  3   1.80%   3.59% #
# [ 36, 38)  2   1.20%   4.79% #
# [ 38, 40)  3   1.80%   6.59% #
# [ 40, 42)  7   4.19%  10.78% ###
# [ 42, 44)  5   2.99%  13.77% ##
# [ 44, 46)  6   3.59%  17.37% ##
# [ 46, 48) 14   8.38%  25.75% #####
# [ 48, 50)  8   4.79%  30.54% ###
# [ 50, 52)  9   5.39%  35.93% ###
# [ 52, 54)  8   4.79%  40.72% ###
# [ 54, 56) 16   9.58%  50.30% ######
# [ 56, 58) 17  10.18%  60.48% #######
# [ 58, 60) 22  13.17%  73.65% ########
# [ 60, 62) 26  15.57%  89.22% ##########
# [ 62, 63] 18  10.78% 100.00% #######
#
# Depth by leafs:
# Count: 4563 Average: 4.881 StdDev: 0.436245
# Min: 1 Max: 5 Ignored: 0
# ----------------------------------------------
# [ 1, 2)    3   0.07%   0.07%
# [ 2, 3)   28   0.61%   0.68%
# [ 3, 4)   93   2.04%   2.72%
# [ 4, 5)  261   5.72%   8.44% #
# [ 5, 5] 4178  91.56% 100.00% ##########
#
# Number of training obs by leaf:
# Count: 4563 Average: 2595.18 StdDev: 8129.2
# Min: 5 Max: 66977 Ignored: 0
# ----------------------------------------------
# [     5,  3353) 3902  85.51%  85.51% ##########
# [  3353,  6702)  292   6.40%  91.91% #
# [  6702, 10050)   98   2.15%  94.06%
# [ 10050, 13399)   52   1.14%  95.20%
# [ 13399, 16748)   48   1.05%  96.25%
# [ 16748, 20096)   25   0.55%  96.80%
# [ 20096, 23445)   30   0.66%  97.46%
# [ 23445, 26794)    6   0.13%  97.59%
# [ 26794, 30142)    7   0.15%  97.74%
# [ 30142, 33491)    6   0.13%  97.87%
# [ 33491, 36840)    5   0.11%  97.98%
# [ 36840, 40188)    4   0.09%  98.07%
# [ 40188, 43537)    9   0.20%  98.27%
# [ 43537, 46886)   11   0.24%  98.51%
# [ 46886, 50234)   13   0.28%  98.79%
# [ 50234, 53583)   23   0.50%  99.30%
# [ 53583, 56932)   10   0.22%  99.52%
# [ 56932, 60280)    4   0.09%  99.61%
# [ 60280, 63629)   11   0.24%  99.85%
# [ 63629, 66977]    7   0.15% 100.00%
#
# Attribute in nodes:
# 	560 : LongRunHighGrayLevelEmphasis [NUMERICAL]
# 	422 : GrayLevelNonUniformity [NUMERICAL]
# 	389 : RunEntropy [NUMERICAL]
# 	363 : ShortRunHighGrayLevelEmphasis [NUMERICAL]
# 	336 : ShortRunLowGrayLevelEmphasis [NUMERICAL]
# 	329 : GrayLevelVariance [NUMERICAL]
# 	318 : LongRunLowGrayLevelEmphasis [NUMERICAL]
# 	248 : RunLengthNonUniformityNormalized [NUMERICAL]
# 	242 : LowGrayLevelRunEmphasis [NUMERICAL]
# 	236 : ShortRunEmphasis [NUMERICAL]
# 	233 : HighGrayLevelRunEmphasis [NUMERICAL]
# 	228 : RunVariance [NUMERICAL]
# 	195 : GrayLevelNonUniformityNormalized [NUMERICAL]
# 	118 : LongRunEmphasis [NUMERICAL]
# 	101 : RunLengthNonUniformity [NUMERICAL]
# 	78 : RunPercentage [NUMERICAL]
#
# Attribute in nodes with depth <= 0:
# 	62 : LongRunHighGrayLevelEmphasis [NUMERICAL]
# 	25 : GrayLevelNonUniformity [NUMERICAL]
# 	16 : RunVariance [NUMERICAL]
# 	16 : LongRunLowGrayLevelEmphasis [NUMERICAL]
# 	13 : RunLengthNonUniformityNormalized [NUMERICAL]
# 	6 : ShortRunLowGrayLevelEmphasis [NUMERICAL]
# 	6 : LowGrayLevelRunEmphasis [NUMERICAL]
# 	5 : ShortRunHighGrayLevelEmphasis [NUMERICAL]
# 	5 : RunEntropy [NUMERICAL]
# 	4 : GrayLevelVariance [NUMERICAL]
# 	3 : HighGrayLevelRunEmphasis [NUMERICAL]
# 	2 : GrayLevelNonUniformityNormalized [NUMERICAL]
# 	1 : ShortRunEmphasis [NUMERICAL]
# 	1 : RunPercentage [NUMERICAL]
# 	1 : RunLengthNonUniformity [NUMERICAL]
# 	1 : LongRunEmphasis [NUMERICAL]
#
# Attribute in nodes with depth <= 1:
# 	100 : LongRunHighGrayLevelEmphasis [NUMERICAL]
# 	57 : RunLengthNonUniformityNormalized [NUMERICAL]
# 	47 : GrayLevelNonUniformity [NUMERICAL]
# 	43 : ShortRunHighGrayLevelEmphasis [NUMERICAL]
# 	39 : ShortRunEmphasis [NUMERICAL]
# 	35 : LongRunLowGrayLevelEmphasis [NUMERICAL]
# 	30 : RunVariance [NUMERICAL]
# 	30 : RunEntropy [NUMERICAL]
# 	22 : ShortRunLowGrayLevelEmphasis [NUMERICAL]
# 	21 : LowGrayLevelRunEmphasis [NUMERICAL]
# 	21 : GrayLevelVariance [NUMERICAL]
# 	15 : LongRunEmphasis [NUMERICAL]
# 	15 : HighGrayLevelRunEmphasis [NUMERICAL]
# 	10 : RunLengthNonUniformity [NUMERICAL]
# 	9 : GrayLevelNonUniformityNormalized [NUMERICAL]
# 	4 : RunPercentage [NUMERICAL]
#
# Attribute in nodes with depth <= 2:
# 	184 : LongRunHighGrayLevelEmphasis [NUMERICAL]
# 	131 : GrayLevelNonUniformity [NUMERICAL]
# 	99 : RunEntropy [NUMERICAL]
# 	90 : RunLengthNonUniformityNormalized [NUMERICAL]
# 	83 : ShortRunHighGrayLevelEmphasis [NUMERICAL]
# 	79 : LongRunLowGrayLevelEmphasis [NUMERICAL]
# 	69 : ShortRunLowGrayLevelEmphasis [NUMERICAL]
# 	67 : ShortRunEmphasis [NUMERICAL]
# 	57 : RunVariance [NUMERICAL]
# 	57 : LowGrayLevelRunEmphasis [NUMERICAL]
# 	57 : GrayLevelVariance [NUMERICAL]
# 	42 : HighGrayLevelRunEmphasis [NUMERICAL]
# 	40 : GrayLevelNonUniformityNormalized [NUMERICAL]
# 	31 : LongRunEmphasis [NUMERICAL]
# 	28 : RunLengthNonUniformity [NUMERICAL]
# 	18 : RunPercentage [NUMERICAL]
#
# Attribute in nodes with depth <= 3:
# 	308 : LongRunHighGrayLevelEmphasis [NUMERICAL]
# 	242 : GrayLevelNonUniformity [NUMERICAL]
# 	213 : RunEntropy [NUMERICAL]
# 	177 : ShortRunLowGrayLevelEmphasis [NUMERICAL]
# 	166 : ShortRunHighGrayLevelEmphasis [NUMERICAL]
# 	166 : LongRunLowGrayLevelEmphasis [NUMERICAL]
# 	158 : RunLengthNonUniformityNormalized [NUMERICAL]
# 	146 : GrayLevelVariance [NUMERICAL]
# 	137 : ShortRunEmphasis [NUMERICAL]
# 	125 : RunVariance [NUMERICAL]
# 	122 : LowGrayLevelRunEmphasis [NUMERICAL]
# 	120 : HighGrayLevelRunEmphasis [NUMERICAL]
# 	86 : GrayLevelNonUniformityNormalized [NUMERICAL]
# 	53 : LongRunEmphasis [NUMERICAL]
# 	50 : RunLengthNonUniformity [NUMERICAL]
# 	38 : RunPercentage [NUMERICAL]
#
# Attribute in nodes with depth <= 5:
# 	560 : LongRunHighGrayLevelEmphasis [NUMERICAL]
# 	422 : GrayLevelNonUniformity [NUMERICAL]
# 	389 : RunEntropy [NUMERICAL]
# 	363 : ShortRunHighGrayLevelEmphasis [NUMERICAL]
# 	336 : ShortRunLowGrayLevelEmphasis [NUMERICAL]
# 	329 : GrayLevelVariance [NUMERICAL]
# 	318 : LongRunLowGrayLevelEmphasis [NUMERICAL]
# 	248 : RunLengthNonUniformityNormalized [NUMERICAL]
# 	242 : LowGrayLevelRunEmphasis [NUMERICAL]
# 	236 : ShortRunEmphasis [NUMERICAL]
# 	233 : HighGrayLevelRunEmphasis [NUMERICAL]
# 	228 : RunVariance [NUMERICAL]
# 	195 : GrayLevelNonUniformityNormalized [NUMERICAL]
# 	118 : LongRunEmphasis [NUMERICAL]
# 	101 : RunLengthNonUniformity [NUMERICAL]
# 	78 : RunPercentage [NUMERICAL]
#
# Condition type in nodes:
# 	4396 : HigherCondition
# Condition type in nodes with depth <= 0:
# 	167 : HigherCondition
# Condition type in nodes with depth <= 1:
# 	498 : HigherCondition
# Condition type in nodes with depth <= 2:
# 	1132 : HigherCondition
# Condition type in nodes with depth <= 3:
# 	2307 : HigherCondition
# Condition type in nodes with depth <= 5:
# 	4396 : HigherCondition
#
# Training logs:
# Number of iteration to final model: 167
# 	Iter:1 train-loss:1.282433 valid-loss:1.283069  train-accuracy:0.845332 valid-accuracy:0.846523
# 	Iter:2 train-loss:1.196772 valid-loss:1.198677  train-accuracy:0.851446 valid-accuracy:0.844904
# 	Iter:3 train-loss:1.124672 valid-loss:1.127235  train-accuracy:0.851480 valid-accuracy:0.848084
# 	Iter:4 train-loss:1.063500 valid-loss:1.067043  train-accuracy:0.854831 valid-accuracy:0.845934
# 	Iter:5 train-loss:1.011032 valid-loss:1.016209  train-accuracy:0.853816 valid-accuracy:0.847432
# 	Iter:6 train-loss:0.965515 valid-loss:0.972673  train-accuracy:0.858464 valid-accuracy:0.848433
# 	Iter:16 train-loss:0.713505 valid-loss:0.737172  train-accuracy:0.875091 valid-accuracy:0.864711
# 	Iter:26 train-loss:0.610516 valid-loss:0.649781  train-accuracy:0.883687 valid-accuracy:0.870129
# 	Iter:36 train-loss:0.549788 valid-loss:0.604544  train-accuracy:0.894768 valid-accuracy:0.876535
# 	Iter:46 train-loss:0.518230 valid-loss:0.587137  train-accuracy:0.899512 valid-accuracy:0.878349
# 	Iter:56 train-loss:0.494113 valid-loss:0.575757  train-accuracy:0.902676 valid-accuracy:0.882395
# 	Iter:66 train-loss:0.476515 valid-loss:0.569088  train-accuracy:0.907308 valid-accuracy:0.883579
# 	Iter:76 train-loss:0.461569 valid-loss:0.566394  train-accuracy:0.910720 valid-accuracy:0.883656
# 	Iter:86 train-loss:0.448008 valid-loss:0.563171  train-accuracy:0.913583 valid-accuracy:0.883453
# 	Iter:96 train-loss:0.436577 valid-loss:0.560036  train-accuracy:0.917182 valid-accuracy:0.882557
# 	Iter:106 train-loss:0.427058 valid-loss:0.560911  train-accuracy:0.919841 valid-accuracy:0.882697
# 	Iter:116 train-loss:0.416151 valid-loss:0.560411  train-accuracy:0.923585 valid-accuracy:0.883264
# 	Iter:126 train-loss:0.408556 valid-loss:0.559020  train-accuracy:0.925012 valid-accuracy:0.883614
# 	Iter:136 train-loss:0.399004 valid-loss:0.558869  train-accuracy:0.927060 valid-accuracy:0.882088
# 	Iter:146 train-loss:0.390566 valid-loss:0.559030  train-accuracy:0.929727 valid-accuracy:0.881675
# 	Iter:156 train-loss:0.382545 valid-loss:0.558131  train-accuracy:0.931912 valid-accuracy:0.884461
# 	Iter:166 train-loss:0.375576 valid-loss:0.557931  train-accuracy:0.934007 valid-accuracy:0.885925
# 	Iter:176 train-loss:0.369568 valid-loss:0.559305  train-accuracy:0.935379 valid-accuracy:0.885925
# 	Iter:186 train-loss:0.361454 valid-loss:0.560538  train-accuracy:0.936918 valid-accuracy:0.886625
# 	Iter:196 train-loss:0.355302 valid-loss:0.561164  train-accuracy:0.938990 valid-accuracy:0.886422

# %%
# Model features
model.make_inspector().features()
# Out:
# ["GrayLevelNonUniformity" (1; #0),
#  "GrayLevelNonUniformityNormalized" (1; #1),
#  "GrayLevelVariance" (1; #2),
#  "HighGrayLevelRunEmphasis" (1; #3),
#  "LongRunEmphasis" (1; #4),
#  "LongRunHighGrayLevelEmphasis" (1; #5),
#  "LongRunLowGrayLevelEmphasis" (1; #6),
#  "LowGrayLevelRunEmphasis" (1; #7),
#  "RunEntropy" (1; #8),
#  "RunLengthNonUniformity" (1; #9),
#  "RunLengthNonUniformityNormalized" (1; #10),
#  "RunPercentage" (1; #11),
#  "RunVariance" (1; #12),
#  "ShortRunEmphasis" (1; #13),
#  "ShortRunHighGrayLevelEmphasis" (1; #14),
#  "ShortRunLowGrayLevelEmphasis" (1; #15)]

# %%
# Feature importance
model.make_inspector().variable_importances()
# Out:
# {'INV_MEAN_MIN_DEPTH': [("LongRunHighGrayLevelEmphasis" (1; #5),
#    0.27695590755083926),
#   ("GrayLevelNonUniformity" (1; #0), 0.22551914493978245),
#   ("RunLengthNonUniformityNormalized" (1; #10), 0.21108108409230872),
#   ("RunEntropy" (1; #8), 0.20175746781919934),
#   ("LongRunLowGrayLevelEmphasis" (1; #6), 0.19975364899056466),
#   ("RunVariance" (1; #12), 0.19865145138794305),
#   ("ShortRunHighGrayLevelEmphasis" (1; #14), 0.19834047816399963),
#   ("ShortRunLowGrayLevelEmphasis" (1; #15), 0.19521311812311856),
#   ("ShortRunEmphasis" (1; #13), 0.1937804995172629),
#   ("GrayLevelVariance" (1; #2), 0.190753240298602),
#   ("LowGrayLevelRunEmphasis" (1; #7), 0.18712127929732233),
#   ("HighGrayLevelRunEmphasis" (1; #3), 0.18509514537619093),
#   ("GrayLevelNonUniformityNormalized" (1; #1), 0.1822049139790089),
#   ("LongRunEmphasis" (1; #4), 0.17984998599701088),
#   ("RunLengthNonUniformity" (1; #9), 0.17829088074665095),
#   ("RunPercentage" (1; #11), 0.17484240333605844)],
#  'SUM_SCORE': [("LongRunHighGrayLevelEmphasis" (1; #5), 32989.16513508521),
#   ("ShortRunHighGrayLevelEmphasis" (1; #14), 6213.806191230215),
#   ("GrayLevelNonUniformity" (1; #0), 5955.279035711255),
#   ("RunEntropy" (1; #8), 4476.1085032022775),
#   ("LowGrayLevelRunEmphasis" (1; #7), 4459.137137508983),
#   ("ShortRunEmphasis" (1; #13), 3612.0328437027),
#   ("LongRunLowGrayLevelEmphasis" (1; #6), 3315.936065013576),
#   ("ShortRunLowGrayLevelEmphasis" (1; #15), 3223.8807903999787),
#   ("RunLengthNonUniformityNormalized" (1; #10), 2682.4937614304763),
#   ("RunVariance" (1; #12), 2356.1678610956487),
#   ("HighGrayLevelRunEmphasis" (1; #3), 1367.0101492173499),
#   ("GrayLevelVariance" (1; #2), 1286.4711289745062),
#   ("GrayLevelNonUniformityNormalized" (1; #1), 852.8624335235412),
#   ("RunLengthNonUniformity" (1; #9), 389.31579002055895),
#   ("LongRunEmphasis" (1; #4), 360.45210798102795),
#   ("RunPercentage" (1; #11), 268.03384590780144)],
#  'NUM_AS_ROOT': [("LongRunHighGrayLevelEmphasis" (1; #5), 62.0),
#   ("GrayLevelNonUniformity" (1; #0), 25.0),
#   ("LongRunLowGrayLevelEmphasis" (1; #6), 16.0),
#   ("RunVariance" (1; #12), 16.0),
#   ("RunLengthNonUniformityNormalized" (1; #10), 13.0),
#   ("LowGrayLevelRunEmphasis" (1; #7), 6.0),
#   ("ShortRunLowGrayLevelEmphasis" (1; #15), 6.0),
#   ("RunEntropy" (1; #8), 5.0),
#   ("ShortRunHighGrayLevelEmphasis" (1; #14), 5.0),
#   ("GrayLevelVariance" (1; #2), 4.0),
#   ("HighGrayLevelRunEmphasis" (1; #3), 3.0),
#   ("GrayLevelNonUniformityNormalized" (1; #1), 2.0),
#   ("LongRunEmphasis" (1; #4), 1.0),
#   ("RunLengthNonUniformity" (1; #9), 1.0),
#   ("RunPercentage" (1; #11), 1.0),
#   ("ShortRunEmphasis" (1; #13), 1.0)],
#  'NUM_NODES': [("LongRunHighGrayLevelEmphasis" (1; #5), 560.0),
#   ("GrayLevelNonUniformity" (1; #0), 422.0),
#   ("RunEntropy" (1; #8), 389.0),
#   ("ShortRunHighGrayLevelEmphasis" (1; #14), 363.0),
#   ("ShortRunLowGrayLevelEmphasis" (1; #15), 336.0),
#   ("GrayLevelVariance" (1; #2), 329.0),
#   ("LongRunLowGrayLevelEmphasis" (1; #6), 318.0),
#   ("RunLengthNonUniformityNormalized" (1; #10), 248.0),
#   ("LowGrayLevelRunEmphasis" (1; #7), 242.0),
#   ("ShortRunEmphasis" (1; #13), 236.0),
#   ("HighGrayLevelRunEmphasis" (1; #3), 233.0),
#   ("RunVariance" (1; #12), 228.0),
#   ("GrayLevelNonUniformityNormalized" (1; #1), 195.0),
#   ("LongRunEmphasis" (1; #4), 118.0),
#   ("RunLengthNonUniformity" (1; #9), 101.0),
#   ("RunPercentage" (1; #11), 78.0)]}

# %%
# Model self evaluation
model.make_inspector().evaluation()
# Out:
# Evaluation(num_examples=None, accuracy=0.8858546614646912, loss=0.5576654076576233, rmse=None, ndcg=None, aucs=None, auuc=None, qini=None)

# %%
logs = model.make_inspector().training_logs()

plt.figure(figsize=(12, 4))
plt.subplot(1, 2, 1)
plt.plot([log.num_trees for log in logs], [log.evaluation.accuracy for log in logs])
plt.xlabel("Number of trees")
plt.ylabel("Accuracy (out-of-bag)")
plt.subplot(1, 2, 2)
plt.plot([log.num_trees for log in logs], [log.evaluation.loss for log in logs])
plt.xlabel("Number of trees")
plt.ylabel("Logloss (out-of-bag)")
plt.show()

# %% [markdown]
# Calculate the score of our hold-out validation dataset

# %%
predictions = model.predict(val_ds)
y_true      = validation_data["label"]

from sklearn.metrics import roc_auc_score
ROC_AUC = roc_auc_score(y_true, predictions)
print("The ROC AUC score is %.5f" % ROC_AUC )
# Out:
#  1/12 [=>............................] - ETA: 0s
# 12/12 [==============================] - 0s 4ms/step
# The ROC AUC score is 0.95667

# %%
# Compute binary classification metrics with sklearn
import numpy as np
from sklearn.metrics import (
    accuracy_score,
    precision_score,
    recall_score,
    f1_score,
    roc_auc_score,
    average_precision_score,
    confusion_matrix,
    classification_report,
    matthews_corrcoef,
    log_loss,
    brier_score_loss,
)

# Get predictions (probabilities or class labels)
preds = model.predict(test_ds)
# If model outputs probabilities, convert to labels by threshold 0.5
if preds.ndim == 2:
    # For TFDF classification, preds may be class probabilities with shape (N, 2)
    if preds.shape[1] == 2:
        pos_probs = preds[:, 1]
    else:
        # If single-probability column (positive class)
        pos_probs = preds[:, -1]
    y_pred = (pos_probs >= 0.5).astype(int)
else:
    # Already class labels
    y_pred = preds.astype(int)
    pos_probs = None

# Ground truth labels (must be 0/1 integers)
y_true = test_data["label"].astype(int).to_numpy()

# Core metrics
metrics = {}
metrics["accuracy"] = accuracy_score(y_true, y_pred)
metrics["precision"] = precision_score(y_true, y_pred, zero_division=0)
metrics["recall"] = recall_score(y_true, y_pred, zero_division=0)
metrics["f1"] = f1_score(y_true, y_pred, zero_division=0)
metrics["mcc"] = matthews_corrcoef(y_true, y_pred)

# Probabilistic metrics (only if we have probabilities)
if pos_probs is not None:
    metrics["roc_auc"] = roc_auc_score(y_true, pos_probs)
    metrics["pr_auc"] = average_precision_score(y_true, pos_probs)
    metrics["log_loss"] = log_loss(y_true, pos_probs, labels=[0,1])
    metrics["brier_score"] = brier_score_loss(y_true, pos_probs)

# Confusion matrix and detailed report
cm = confusion_matrix(y_true, y_pred, labels=[0,1])
report = classification_report(y_true, y_pred, digits=4)

print("Sklearn binary metrics:")
for k, v in metrics.items():
    print(f"{k}: {v:.4f}")
print("\nConfusion matrix:\n", cm)
print("\nClassification report:\n", report)
# Out:
#  1/23 [>.............................] - ETA: 1s
# 14/23 [=================>............] - ETA: 0s
# 23/23 [==============================] - 0s 4ms/step
# Sklearn binary metrics:
# accuracy: 0.9213
# precision: 0.4673
# recall: 0.8329
# f1: 0.5987
# mcc: 0.5876
# roc_auc: 0.9548
# pr_auc: 0.7742
# log_loss: 0.2136
# brier_score: 0.0605
#
# Confusion matrix:
#  [[19420  1506]
#  [  265  1321]]
#
# Classification report:
#                precision    recall  f1-score   support
#
#            0     0.9865    0.9280    0.9564     20926
#            1     0.4673    0.8329    0.5987      1586
#
#     accuracy                         0.9213     22512
#    macro avg     0.7269    0.8805    0.7775     22512
# weighted avg     0.9500    0.9213    0.9312     22512
