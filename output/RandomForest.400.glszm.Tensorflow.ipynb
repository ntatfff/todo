# %%
# Import packages and modules
import numpy  as np
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow_decision_forests as tfdf

from sklearn.model_selection import train_test_split
# Out:
# 2026-07-04 09:10:29.357368: I tensorflow/core/util/port.cc:113] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2026-07-04 09:10:29.398191: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2026-07-04 09:10:33.789689: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
# Check the version of TensorFlow Decision Forests
print("Found TensorFlow Decision Forests v" + tfdf.__version__)
# Out:
# Found TensorFlow Decision Forests v1.9.1

# %%
datasetPath = 'dataset/firstorder/kernel5-radius5/dataset.csv'

# %%
# Parameters
datasetPath = "dataset/glszm/kernel5-radius5/400.dataset.csv"

# %%
# train/validation/test = 70/10/20
dataset = pd.read_csv(datasetPath)

train_data, temp_data = train_test_split(dataset, test_size=0.3, random_state=42)
validation_data, test_data = train_test_split(temp_data, test_size=2/3, random_state=42)

# %%
from sklearn.utils.class_weight import compute_class_weight

# tinh class weight tren tap train
classes = np.array([0, 1])
weights = compute_class_weight(class_weight="balanced", classes=classes, y=train_data["label"])
class_weight = {0: weights[0], 1: weights[1]}

# gan sample_weight cho tung dong
train_data["sample_weight"] = train_data["label"].map(class_weight)
validation_data["sample_weight"] = validation_data["label"].map(class_weight)
test_data["sample_weight"] = test_data["label"].map(class_weight)

# Convert the dataset into a TensorFlow dataset.
train_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    train_data, label="label", weight="sample_weight"
)         
val_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    validation_data, label="label", weight="sample_weight"
)
test_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    test_data, label="label", weight="sample_weight"
)
# Out:
# 2026-07-04 09:10:48.010219: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:984] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2026-07-04 09:10:48.011672: W tensorflow/core/common_runtime/gpu/gpu_device.cc:2251] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...

# %%
import keras

# %%
# %%time

# Train a Random Forest model.
model = tfdf.keras.RandomForestModel()

# Add evaluation metrics
model.compile(
    metrics=["accuracy"]
)
model.fit(x=train_ds)

# # Train a Gradient Boosted Trees model.
# model = tfdf.keras.GradientBoostedTreesModel(num_trees=1500)
# model.fit(train_ds)
# Out:
# Use /tmp/tmps2a9sszh as temporary training directory
# Reading training dataset...
# Training dataset read in 0:00:03.740773. Found 315417 examples.
# Training model...
# [INFO 26-07-04 09:11:27.5791 UTC kernel.cc:1233] Loading model from path /tmp/tmps2a9sszh/model/ with prefix b04924e96e0e4183
# [INFO 26-07-04 09:11:29.7600 UTC decision_forest.cc:734] Model loaded with 300 root(s), 1788474 node(s), and 16 input feature(s).
# [INFO 26-07-04 09:11:29.7600 UTC abstract_model.cc:1362] Engine "RandomForestOptPred" built
# [INFO 26-07-04 09:11:29.7600 UTC kernel.cc:1061] Use fast generic engine
# Model trained in 0:00:38.140515
# Compiling model...
# Model compiled.
# CPU times: user 6min 50s, sys: 2.61 s, total: 6min 52s
# Wall time: 45.1 s

# %%
# Evaluate the model
evaluate = model.evaluate(val_ds, return_dict=True)
print()

for name, value in evaluate.items():
    print(f"{name}: {value:.4f}")
# Out:
# WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
#  1/46 [..............................] - ETA: 2:14 - loss: 0.0000e+00 - accuracy: 0.9120
#  3/46 [>.............................] - ETA: 1s - loss: 0.0000e+00 - accuracy: 0.9093
#  5/46 [==>...........................] - ETA: 1s - loss: 0.0000e+00 - accuracy: 0.9064
#  7/46 [===>..........................] - ETA: 1s - loss: 0.0000e+00 - accuracy: 0.9067
#  9/46 [====>.........................] - ETA: 1s - loss: 0.0000e+00 - accuracy: 0.9083
# 11/46 [======>.......................] - ETA: 1s - loss: 0.0000e+00 - accuracy: 0.9095
# 13/46 [=======>......................] - ETA: 1s - loss: 0.0000e+00 - accuracy: 0.9072
# 15/46 [========>.....................] - ETA: 1s - loss: 0.0000e+00 - accuracy: 0.9066
# 17/46 [==========>...................] - ETA: 1s - loss: 0.0000e+00 - accuracy: 0.9082
# 19/46 [===========>..................] - ETA: 1s - loss: 0.0000e+00 - accuracy: 0.9086
# 21/46 [============>.................] - ETA: 1s - loss: 0.0000e+00 - accuracy: 0.9081
# 23/46 [==============>...............] - ETA: 0s - loss: 0.0000e+00 - accuracy: 0.9079
# 25/46 [===============>..............] - ETA: 0s - loss: 0.0000e+00 - accuracy: 0.9076
# 27/46 [================>.............] - ETA: 0s - loss: 0.0000e+00 - accuracy: 0.9072
# 29/46 [=================>............] - ETA: 0s - loss: 0.0000e+00 - accuracy: 0.9071
# 31/46 [===================>..........] - ETA: 0s - loss: 0.0000e+00 - accuracy: 0.9073
# 33/46 [====================>.........] - ETA: 0s - loss: 0.0000e+00 - accuracy: 0.9071
# 35/46 [=====================>........] - ETA: 0s - loss: 0.0000e+00 - accuracy: 0.9067
# 37/46 [=======================>......] - ETA: 0s - loss: 0.0000e+00 - accuracy: 0.9071
# 39/46 [========================>.....] - ETA: 0s - loss: 0.0000e+00 - accuracy: 0.9075
# 41/46 [=========================>....] - ETA: 0s - loss: 0.0000e+00 - accuracy: 0.9079
# 43/46 [===========================>..] - ETA: 0s - loss: 0.0000e+00 - accuracy: 0.9078
# 45/46 [============================>.] - ETA: 0s - loss: 0.0000e+00 - accuracy: 0.9079
# 46/46 [==============================] - 5s 39ms/step - loss: 0.0000e+00 - accuracy: 0.9079
# loss: 0.0000
# accuracy: 0.9079

# %%
# Model Summary
model.summary()
# Out:
# Model: "random_forest_model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
# =================================================================
# Total params: 1 (1.00 Byte)
# Trainable params: 0 (0.00 Byte)
# Non-trainable params: 1 (1.00 Byte)
# _________________________________________________________________
# Type: "RANDOM_FOREST"
# Task: CLASSIFICATION
# Label: "__LABEL"
#
# Input Features (16):
# 	GrayLevelNonUniformity
# 	GrayLevelNonUniformityNormalized
# 	GrayLevelVariance
# 	HighGrayLevelZoneEmphasis
# 	LargeAreaEmphasis
# 	LargeAreaHighGrayLevelEmphasis
# 	LargeAreaLowGrayLevelEmphasis
# 	LowGrayLevelZoneEmphasis
# 	SizeZoneNonUniformity
# 	SizeZoneNonUniformityNormalized
# 	SmallAreaEmphasis
# 	SmallAreaHighGrayLevelEmphasis
# 	SmallAreaLowGrayLevelEmphasis
# 	ZoneEntropy
# 	ZonePercentage
# 	ZoneVariance
#
# Trained with weights
#
# Variable Importance: INV_MEAN_MIN_DEPTH:
#     1.        "HighGrayLevelZoneEmphasis"  0.227951 ################
#     2.           "GrayLevelNonUniformity"  0.151250 #######
#     3.    "SmallAreaLowGrayLevelEmphasis"  0.131087 #####
#     4.         "LowGrayLevelZoneEmphasis"  0.128087 #####
#     5.    "LargeAreaLowGrayLevelEmphasis"  0.126515 ####
#     6.   "LargeAreaHighGrayLevelEmphasis"  0.110639 ###
#     7.   "SmallAreaHighGrayLevelEmphasis"  0.103463 ##
#     8.  "SizeZoneNonUniformityNormalized"  0.098319 #
#     9.                "GrayLevelVariance"  0.095801 #
#    10.                "SmallAreaEmphasis"  0.091601 #
#    11.            "SizeZoneNonUniformity"  0.089396
#    12. "GrayLevelNonUniformityNormalized"  0.088894
#    13.                      "ZoneEntropy"  0.088578
#    14.                     "ZoneVariance"  0.086483
#    15.                   "ZonePercentage"  0.082724
#    16.                "LargeAreaEmphasis"  0.080431
#
# Variable Importance: NUM_AS_ROOT:
#     1.        "HighGrayLevelZoneEmphasis" 93.000000 ################
#     2.    "SmallAreaLowGrayLevelEmphasis" 62.000000 ##########
#     3.    "LargeAreaLowGrayLevelEmphasis" 48.000000 ########
#     4.         "LowGrayLevelZoneEmphasis" 46.000000 #######
#     5.   "SmallAreaHighGrayLevelEmphasis" 18.000000 ##
#     6. "GrayLevelNonUniformityNormalized" 12.000000 #
#     7.                "GrayLevelVariance" 12.000000 #
#     8.                      "ZoneEntropy"  5.000000
#     9.   "LargeAreaHighGrayLevelEmphasis"  3.000000
#    10.                     "ZoneVariance"  1.000000
#
# Variable Importance: NUM_NODES:
#     1.   "LargeAreaHighGrayLevelEmphasis" 71237.000000 ################
#     2.    "LargeAreaLowGrayLevelEmphasis" 70387.000000 ###############
#     3.           "GrayLevelNonUniformity" 68481.000000 ##############
#     4.                     "ZoneVariance" 58714.000000 ########
#     5.        "HighGrayLevelZoneEmphasis" 57918.000000 ########
#     6.         "LowGrayLevelZoneEmphasis" 57772.000000 ########
#     7.                "GrayLevelVariance" 57020.000000 #######
#     8.                      "ZoneEntropy" 56489.000000 #######
#     9.    "SmallAreaLowGrayLevelEmphasis" 54356.000000 ######
#    10. "GrayLevelNonUniformityNormalized" 53271.000000 #####
#    11.   "SmallAreaHighGrayLevelEmphasis" 52694.000000 #####
#    12.                "LargeAreaEmphasis" 51515.000000 ####
#    13.            "SizeZoneNonUniformity" 47393.000000 ##
#    14.  "SizeZoneNonUniformityNormalized" 47117.000000 ##
#    15.                "SmallAreaEmphasis" 46449.000000 #
#    16.                   "ZonePercentage" 43274.000000
#
# Variable Importance: SUM_SCORE:
#     1.        "HighGrayLevelZoneEmphasis" 8520666.004808 ################
#     2.           "GrayLevelNonUniformity" 5485888.418261 #########
#     3.    "SmallAreaLowGrayLevelEmphasis" 4628929.064534 #######
#     4.    "LargeAreaLowGrayLevelEmphasis" 4394365.292125 ######
#     5.         "LowGrayLevelZoneEmphasis" 4316091.529845 ######
#     6.   "LargeAreaHighGrayLevelEmphasis" 3207841.602102 ####
#     7.   "SmallAreaHighGrayLevelEmphasis" 2867613.197156 ###
#     8.  "SizeZoneNonUniformityNormalized" 2344074.357740 ##
#     9.                "SmallAreaEmphasis" 2100495.289423 #
#    10.                "GrayLevelVariance" 2089734.478845 #
#    11.                      "ZoneEntropy" 1975954.332022 #
#    12.            "SizeZoneNonUniformity" 1759563.628782 #
#    13.                     "ZoneVariance" 1704977.749358
#    14. "GrayLevelNonUniformityNormalized" 1700768.641943
#    15.                   "ZonePercentage" 1322197.402327
#    16.                "LargeAreaEmphasis" 1250648.664922
#
#
#
# Winner takes all: true
# Out-of-bag evaluation: accuracy:0.849113 logloss:0.519703
# Number of trees: 300
# Total number of nodes: 1788474
#
# Number of nodes by tree:
# Count: 300 Average: 5961.58 StdDev: 378.954
# Min: 4887 Max: 7095 Ignored: 0
# ----------------------------------------------
# [ 4887, 4997)  2   0.67%   0.67% #
# [ 4997, 5107)  3   1.00%   1.67% #
# [ 5107, 5218)  6   2.00%   3.67% ##
# [ 5218, 5328) 13   4.33%   8.00% ###
# [ 5328, 5439) 10   3.33%  11.33% ###
# [ 5439, 5549) 10   3.33%  14.67% ###
# [ 5549, 5660) 16   5.33%  20.00% ####
# [ 5660, 5770) 23   7.67%  27.67% ######
# [ 5770, 5881) 38  12.67%  40.33% ##########
# [ 5881, 5991) 26   8.67%  49.00% #######
# [ 5991, 6101) 35  11.67%  60.67% #########
# [ 6101, 6212) 27   9.00%  69.67% #######
# [ 6212, 6322) 37  12.33%  82.00% ##########
# [ 6322, 6433) 27   9.00%  91.00% #######
# [ 6433, 6543) 19   6.33%  97.33% #####
# [ 6543, 6654)  4   1.33%  98.67% #
# [ 6654, 6764)  1   0.33%  99.00%
# [ 6764, 6875)  2   0.67%  99.67% #
# [ 6875, 6985)  0   0.00%  99.67%
# [ 6985, 7095]  1   0.33% 100.00%
#
# Depth by leafs:
# Count: 894387 Average: 13.2771 StdDev: 1.89598
# Min: 4 Max: 15 Ignored: 0
# ----------------------------------------------
# [  4,  5)     14   0.00%   0.00%
# [  5,  6)    160   0.02%   0.02%
# [  6,  7)   1233   0.14%   0.16%
# [  7,  8)   4460   0.50%   0.66%
# [  8,  9)  12078   1.35%   2.01%
# [  9, 10)  25863   2.89%   4.90% #
# [ 10, 11)  46575   5.21%  10.11% #
# [ 11, 12)  73325   8.20%  18.30% ##
# [ 12, 13) 102820  11.50%  29.80% ###
# [ 13, 14) 131542  14.71%  44.51% ####
# [ 14, 15) 154971  17.33%  61.83% #####
# [ 15, 15] 341346  38.17% 100.00% ##########
#
# Number of training obs by leaf:
# Count: 894387 Average: 105.799 StdDev: 518.185
# Min: 5 Max: 34456 Ignored: 0
# ----------------------------------------------
# [     5,  1727) 886395  99.11%  99.11% ##########
# [  1727,  3450)   5036   0.56%  99.67%
# [  3450,  5172)   1399   0.16%  99.83%
# [  5172,  6895)    581   0.06%  99.89%
# [  6895,  8618)    312   0.03%  99.93%
# [  8618, 10340)    207   0.02%  99.95%
# [ 10340, 12063)    126   0.01%  99.96%
# [ 12063, 13785)     90   0.01%  99.97%
# [ 13785, 15508)     85   0.01%  99.98%
# [ 15508, 17231)     53   0.01%  99.99%
# [ 17231, 18953)     42   0.00%  99.99%
# [ 18953, 20676)     24   0.00% 100.00%
# [ 20676, 22398)     13   0.00% 100.00%
# [ 22398, 24121)      8   0.00% 100.00%
# [ 24121, 25844)      6   0.00% 100.00%
# [ 25844, 27566)      5   0.00% 100.00%
# [ 27566, 29289)      1   0.00% 100.00%
# [ 29289, 31011)      2   0.00% 100.00%
# [ 31011, 32734)      0   0.00% 100.00%
# [ 32734, 34456]      2   0.00% 100.00%
#
# Attribute in nodes:
# 	71237 : LargeAreaHighGrayLevelEmphasis [NUMERICAL]
# 	70387 : LargeAreaLowGrayLevelEmphasis [NUMERICAL]
# 	68481 : GrayLevelNonUniformity [NUMERICAL]
# 	58714 : ZoneVariance [NUMERICAL]
# 	57918 : HighGrayLevelZoneEmphasis [NUMERICAL]
# 	57772 : LowGrayLevelZoneEmphasis [NUMERICAL]
# 	57020 : GrayLevelVariance [NUMERICAL]
# 	56489 : ZoneEntropy [NUMERICAL]
# 	54356 : SmallAreaLowGrayLevelEmphasis [NUMERICAL]
# 	53271 : GrayLevelNonUniformityNormalized [NUMERICAL]
# 	52694 : SmallAreaHighGrayLevelEmphasis [NUMERICAL]
# 	51515 : LargeAreaEmphasis [NUMERICAL]
# 	47393 : SizeZoneNonUniformity [NUMERICAL]
# 	47117 : SizeZoneNonUniformityNormalized [NUMERICAL]
# 	46449 : SmallAreaEmphasis [NUMERICAL]
# 	43274 : ZonePercentage [NUMERICAL]
#
# Attribute in nodes with depth <= 0:
# 	93 : HighGrayLevelZoneEmphasis [NUMERICAL]
# 	62 : SmallAreaLowGrayLevelEmphasis [NUMERICAL]
# 	48 : LargeAreaLowGrayLevelEmphasis [NUMERICAL]
# 	46 : LowGrayLevelZoneEmphasis [NUMERICAL]
# 	18 : SmallAreaHighGrayLevelEmphasis [NUMERICAL]
# 	12 : GrayLevelVariance [NUMERICAL]
# 	12 : GrayLevelNonUniformityNormalized [NUMERICAL]
# 	5 : ZoneEntropy [NUMERICAL]
# 	3 : LargeAreaHighGrayLevelEmphasis [NUMERICAL]
# 	1 : ZoneVariance [NUMERICAL]
#
# Attribute in nodes with depth <= 1:
# 	254 : HighGrayLevelZoneEmphasis [NUMERICAL]
# 	150 : SmallAreaLowGrayLevelEmphasis [NUMERICAL]
# 	111 : LowGrayLevelZoneEmphasis [NUMERICAL]
# 	82 : GrayLevelNonUniformity [NUMERICAL]
# 	63 : LargeAreaLowGrayLevelEmphasis [NUMERICAL]
# 	56 : LargeAreaHighGrayLevelEmphasis [NUMERICAL]
# 	51 : SmallAreaHighGrayLevelEmphasis [NUMERICAL]
# 	37 : GrayLevelVariance [NUMERICAL]
# 	33 : GrayLevelNonUniformityNormalized [NUMERICAL]
# 	20 : SizeZoneNonUniformityNormalized [NUMERICAL]
# 	18 : SizeZoneNonUniformity [NUMERICAL]
# 	9 : ZoneEntropy [NUMERICAL]
# 	6 : ZoneVariance [NUMERICAL]
# 	6 : SmallAreaEmphasis [NUMERICAL]
# 	3 : ZonePercentage [NUMERICAL]
# 	1 : LargeAreaEmphasis [NUMERICAL]
#
# Attribute in nodes with depth <= 2:
# 	471 : HighGrayLevelZoneEmphasis [NUMERICAL]
# 	276 : GrayLevelNonUniformity [NUMERICAL]
# 	236 : SmallAreaLowGrayLevelEmphasis [NUMERICAL]
# 	231 : LowGrayLevelZoneEmphasis [NUMERICAL]
# 	138 : LargeAreaHighGrayLevelEmphasis [NUMERICAL]
# 	131 : LargeAreaLowGrayLevelEmphasis [NUMERICAL]
# 	113 : SmallAreaHighGrayLevelEmphasis [NUMERICAL]
# 	100 : SizeZoneNonUniformityNormalized [NUMERICAL]
# 	96 : GrayLevelVariance [NUMERICAL]
# 	86 : SmallAreaEmphasis [NUMERICAL]
# 	78 : SizeZoneNonUniformity [NUMERICAL]
# 	62 : GrayLevelNonUniformityNormalized [NUMERICAL]
# 	35 : ZonePercentage [NUMERICAL]
# 	33 : ZoneEntropy [NUMERICAL]
# 	11 : ZoneVariance [NUMERICAL]
# 	3 : LargeAreaEmphasis [NUMERICAL]
#
# Attribute in nodes with depth <= 3:
# 	845 : HighGrayLevelZoneEmphasis [NUMERICAL]
# 	733 : GrayLevelNonUniformity [NUMERICAL]
# 	408 : LowGrayLevelZoneEmphasis [NUMERICAL]
# 	390 : SmallAreaLowGrayLevelEmphasis [NUMERICAL]
# 	331 : LargeAreaHighGrayLevelEmphasis [NUMERICAL]
# 	300 : LargeAreaLowGrayLevelEmphasis [NUMERICAL]
# 	251 : GrayLevelVariance [NUMERICAL]
# 	228 : SmallAreaHighGrayLevelEmphasis [NUMERICAL]
# 	202 : SizeZoneNonUniformity [NUMERICAL]
# 	200 : SizeZoneNonUniformityNormalized [NUMERICAL]
# 	155 : GrayLevelNonUniformityNormalized [NUMERICAL]
# 	141 : SmallAreaEmphasis [NUMERICAL]
# 	122 : ZoneEntropy [NUMERICAL]
# 	82 : ZonePercentage [NUMERICAL]
# 	64 : ZoneVariance [NUMERICAL]
# 	48 : LargeAreaEmphasis [NUMERICAL]
#
# Attribute in nodes with depth <= 5:
# 	2766 : GrayLevelNonUniformity [NUMERICAL]
# 	2343 : HighGrayLevelZoneEmphasis [NUMERICAL]
# 	1641 : LargeAreaHighGrayLevelEmphasis [NUMERICAL]
# 	1620 : LargeAreaLowGrayLevelEmphasis [NUMERICAL]
# 	1408 : LowGrayLevelZoneEmphasis [NUMERICAL]
# 	1142 : GrayLevelVariance [NUMERICAL]
# 	1103 : SmallAreaLowGrayLevelEmphasis [NUMERICAL]
# 	906 : ZoneEntropy [NUMERICAL]
# 	879 : ZoneVariance [NUMERICAL]
# 	838 : SizeZoneNonUniformity [NUMERICAL]
# 	805 : SmallAreaHighGrayLevelEmphasis [NUMERICAL]
# 	775 : SizeZoneNonUniformityNormalized [NUMERICAL]
# 	676 : GrayLevelNonUniformityNormalized [NUMERICAL]
# 	610 : LargeAreaEmphasis [NUMERICAL]
# 	594 : ZonePercentage [NUMERICAL]
# 	592 : SmallAreaEmphasis [NUMERICAL]
#
# Condition type in nodes:
# 	894087 : HigherCondition
# Condition type in nodes with depth <= 0:
# 	300 : HigherCondition
# Condition type in nodes with depth <= 1:
# 	900 : HigherCondition
# Condition type in nodes with depth <= 2:
# 	2100 : HigherCondition
# Condition type in nodes with depth <= 3:
# 	4500 : HigherCondition
# Condition type in nodes with depth <= 5:
# 	18698 : HigherCondition
# Node format: NOT_SET
#
# Training OOB:
# 	trees: 1, Out-of-bag evaluation: accuracy:0.816064 logloss:6.62971
# 	trees: 11, Out-of-bag evaluation: accuracy:0.826721 logloss:2.73299
# 	trees: 21, Out-of-bag evaluation: accuracy:0.837507 logloss:1.68734
# 	trees: 31, Out-of-bag evaluation: accuracy:0.841173 logloss:1.33145
# 	trees: 41, Out-of-bag evaluation: accuracy:0.843591 logloss:1.14405
# 	trees: 51, Out-of-bag evaluation: accuracy:0.844849 logloss:1.0115
# 	trees: 61, Out-of-bag evaluation: accuracy:0.845851 logloss:0.913659
# 	trees: 71, Out-of-bag evaluation: accuracy:0.845723 logloss:0.854409
# 	trees: 81, Out-of-bag evaluation: accuracy:0.846706 logloss:0.797041
# 	trees: 91, Out-of-bag evaluation: accuracy:0.847159 logloss:0.755764
# 	trees: 101, Out-of-bag evaluation: accuracy:0.847664 logloss:0.727856
# 	trees: 111, Out-of-bag evaluation: accuracy:0.847597 logloss:0.70251
# 	trees: 121, Out-of-bag evaluation: accuracy:0.848045 logloss:0.680746
# 	trees: 131, Out-of-bag evaluation: accuracy:0.848454 logloss:0.66129
# 	trees: 141, Out-of-bag evaluation: accuracy:0.848671 logloss:0.646425
# 	trees: 151, Out-of-bag evaluation: accuracy:0.848573 logloss:0.636735
# 	trees: 161, Out-of-bag evaluation: accuracy:0.848669 logloss:0.619515
# 	trees: 171, Out-of-bag evaluation: accuracy:0.849023 logloss:0.606275
# 	trees: 181, Out-of-bag evaluation: accuracy:0.848894 logloss:0.599308
# 	trees: 191, Out-of-bag evaluation: accuracy:0.849149 logloss:0.591132
# 	trees: 201, Out-of-bag evaluation: accuracy:0.849136 logloss:0.582718
# 	trees: 211, Out-of-bag evaluation: accuracy:0.849283 logloss:0.574982
# 	trees: 221, Out-of-bag evaluation: accuracy:0.849331 logloss:0.562649
# 	trees: 231, Out-of-bag evaluation: accuracy:0.849294 logloss:0.558883
# 	trees: 241, Out-of-bag evaluation: accuracy:0.848706 logloss:0.552241
# 	trees: 251, Out-of-bag evaluation: accuracy:0.84873 logloss:0.546333
# 	trees: 261, Out-of-bag evaluation: accuracy:0.848758 logloss:0.542521
# 	trees: 271, Out-of-bag evaluation: accuracy:0.848919 logloss:0.535984
# 	trees: 281, Out-of-bag evaluation: accuracy:0.849204 logloss:0.530693
# 	trees: 291, Out-of-bag evaluation: accuracy:0.849214 logloss:0.526596
# 	trees: 300, Out-of-bag evaluation: accuracy:0.849113 logloss:0.519703

# %%
# Model features
model.make_inspector().features()
# Out:
# ["GrayLevelNonUniformity" (1; #0),
#  "GrayLevelNonUniformityNormalized" (1; #1),
#  "GrayLevelVariance" (1; #2),
#  "HighGrayLevelZoneEmphasis" (1; #3),
#  "LargeAreaEmphasis" (1; #4),
#  "LargeAreaHighGrayLevelEmphasis" (1; #5),
#  "LargeAreaLowGrayLevelEmphasis" (1; #6),
#  "LowGrayLevelZoneEmphasis" (1; #7),
#  "SizeZoneNonUniformity" (1; #8),
#  "SizeZoneNonUniformityNormalized" (1; #9),
#  "SmallAreaEmphasis" (1; #10),
#  "SmallAreaHighGrayLevelEmphasis" (1; #11),
#  "SmallAreaLowGrayLevelEmphasis" (1; #12),
#  "ZoneEntropy" (1; #13),
#  "ZonePercentage" (1; #14),
#  "ZoneVariance" (1; #15)]

# %%
# Feature importance
model.make_inspector().variable_importances()
# Out:
# {'INV_MEAN_MIN_DEPTH': [("HighGrayLevelZoneEmphasis" (1; #3),
#    0.22795135375868758),
#   ("GrayLevelNonUniformity" (1; #0), 0.1512499152928407),
#   ("SmallAreaLowGrayLevelEmphasis" (1; #12), 0.1310870075698523),
#   ("LowGrayLevelZoneEmphasis" (1; #7), 0.12808738095295785),
#   ("LargeAreaLowGrayLevelEmphasis" (1; #6), 0.12651457414225895),
#   ("LargeAreaHighGrayLevelEmphasis" (1; #5), 0.11063865279931605),
#   ("SmallAreaHighGrayLevelEmphasis" (1; #11), 0.10346264978995806),
#   ("SizeZoneNonUniformityNormalized" (1; #9), 0.09831927624314417),
#   ("GrayLevelVariance" (1; #2), 0.09580062037833582),
#   ("SmallAreaEmphasis" (1; #10), 0.09160112264040726),
#   ("SizeZoneNonUniformity" (1; #8), 0.08939590975844026),
#   ("GrayLevelNonUniformityNormalized" (1; #1), 0.08889421028287972),
#   ("ZoneEntropy" (1; #13), 0.08857771585841696),
#   ("ZoneVariance" (1; #15), 0.08648282617953489),
#   ("ZonePercentage" (1; #14), 0.08272407195530572),
#   ("LargeAreaEmphasis" (1; #4), 0.08043058343196505)],
#  'SUM_SCORE': [("HighGrayLevelZoneEmphasis" (1; #3), 8520666.00480812),
#   ("GrayLevelNonUniformity" (1; #0), 5485888.418261402),
#   ("SmallAreaLowGrayLevelEmphasis" (1; #12), 4628929.0645344565),
#   ("LargeAreaLowGrayLevelEmphasis" (1; #6), 4394365.29212458),
#   ("LowGrayLevelZoneEmphasis" (1; #7), 4316091.529845335),
#   ("LargeAreaHighGrayLevelEmphasis" (1; #5), 3207841.602101873),
#   ("SmallAreaHighGrayLevelEmphasis" (1; #11), 2867613.1971559008),
#   ("SizeZoneNonUniformityNormalized" (1; #9), 2344074.3577398155),
#   ("SmallAreaEmphasis" (1; #10), 2100495.289422984),
#   ("GrayLevelVariance" (1; #2), 2089734.4788449884),
#   ("ZoneEntropy" (1; #13), 1975954.3320221242),
#   ("SizeZoneNonUniformity" (1; #8), 1759563.628782269),
#   ("ZoneVariance" (1; #15), 1704977.7493584412),
#   ("GrayLevelNonUniformityNormalized" (1; #1), 1700768.6419431036),
#   ("ZonePercentage" (1; #14), 1322197.4023274868),
#   ("LargeAreaEmphasis" (1; #4), 1250648.6649222919)],
#  'NUM_AS_ROOT': [("HighGrayLevelZoneEmphasis" (1; #3), 93.0),
#   ("SmallAreaLowGrayLevelEmphasis" (1; #12), 62.0),
#   ("LargeAreaLowGrayLevelEmphasis" (1; #6), 48.0),
#   ("LowGrayLevelZoneEmphasis" (1; #7), 46.0),
#   ("SmallAreaHighGrayLevelEmphasis" (1; #11), 18.0),
#   ("GrayLevelNonUniformityNormalized" (1; #1), 12.0),
#   ("GrayLevelVariance" (1; #2), 12.0),
#   ("ZoneEntropy" (1; #13), 5.0),
#   ("LargeAreaHighGrayLevelEmphasis" (1; #5), 3.0),
#   ("ZoneVariance" (1; #15), 1.0)],
#  'NUM_NODES': [("LargeAreaHighGrayLevelEmphasis" (1; #5), 71237.0),
#   ("LargeAreaLowGrayLevelEmphasis" (1; #6), 70387.0),
#   ("GrayLevelNonUniformity" (1; #0), 68481.0),
#   ("ZoneVariance" (1; #15), 58714.0),
#   ("HighGrayLevelZoneEmphasis" (1; #3), 57918.0),
#   ("LowGrayLevelZoneEmphasis" (1; #7), 57772.0),
#   ("GrayLevelVariance" (1; #2), 57020.0),
#   ("ZoneEntropy" (1; #13), 56489.0),
#   ("SmallAreaLowGrayLevelEmphasis" (1; #12), 54356.0),
#   ("GrayLevelNonUniformityNormalized" (1; #1), 53271.0),
#   ("SmallAreaHighGrayLevelEmphasis" (1; #11), 52694.0),
#   ("LargeAreaEmphasis" (1; #4), 51515.0),
#   ("SizeZoneNonUniformity" (1; #8), 47393.0),
#   ("SizeZoneNonUniformityNormalized" (1; #9), 47117.0),
#   ("SmallAreaEmphasis" (1; #10), 46449.0),
#   ("ZonePercentage" (1; #14), 43274.0)]}

# %%
# Model self evaluation
model.make_inspector().evaluation()
# Out:
# Evaluation(num_examples=315417, accuracy=0.8491126757457932, loss=0.5197032743553922, rmse=None, ndcg=None, aucs=None, auuc=None, qini=None)

# %%
logs = model.make_inspector().training_logs()

plt.figure(figsize=(12, 4))
plt.subplot(1, 2, 1)
plt.plot([log.num_trees for log in logs], [log.evaluation.accuracy for log in logs])
plt.xlabel("Number of trees")
plt.ylabel("Accuracy (out-of-bag)")
plt.subplot(1, 2, 2)
plt.plot([log.num_trees for log in logs], [log.evaluation.loss for log in logs])
plt.xlabel("Number of trees")
plt.ylabel("Logloss (out-of-bag)")
plt.show()

# %% [markdown]
# Calculate the score of our hold-out validation dataset

# %%
predictions = model.predict(val_ds)
y_true      = validation_data["label"]

from sklearn.metrics import roc_auc_score
ROC_AUC = roc_auc_score(y_true, predictions)
print("The ROC AUC score is %.5f" % ROC_AUC )
# Out:
#  1/46 [..............................] - ETA: 5s
#  3/46 [>.............................] - ETA: 1s
#  5/46 [==>...........................] - ETA: 1s
#  7/46 [===>..........................] - ETA: 1s
#  9/46 [====>.........................] - ETA: 1s
# 11/46 [======>.......................] - ETA: 1s
# 13/46 [=======>......................] - ETA: 1s
# 15/46 [========>.....................] - ETA: 1s
# 17/46 [==========>...................] - ETA: 1s
# 19/46 [===========>..................] - ETA: 1s
# 21/46 [============>.................] - ETA: 0s
# 23/46 [==============>...............] - ETA: 0s
# 25/46 [===============>..............] - ETA: 0s
# 27/46 [================>.............] - ETA: 0s
# 29/46 [=================>............] - ETA: 0s
# 31/46 [===================>..........] - ETA: 0s
# 32/46 [===================>..........] - ETA: 0s
# 34/46 [=====================>........] - ETA: 0s
# 36/46 [======================>.......] - ETA: 0s
# 38/46 [=======================>......] - ETA: 0s
# 40/46 [=========================>....] - ETA: 0s
# 42/46 [==========================>...] - ETA: 0s
# 44/46 [===========================>..] - ETA: 0s
# 46/46 [==============================] - 3s 75ms/step
# The ROC AUC score is 0.93194

# %%
# Compute binary classification metrics with sklearn
import numpy as np
from sklearn.metrics import (
    accuracy_score,
    precision_score,
    recall_score,
    f1_score,
    roc_auc_score,
    average_precision_score,
    confusion_matrix,
    classification_report,
    matthews_corrcoef,
    log_loss,
    brier_score_loss,
)

# Get predictions (probabilities or class labels)
preds = model.predict(test_ds)
# If model outputs probabilities, convert to labels by threshold 0.5
if preds.ndim == 2:
    # For TFDF classification, preds may be class probabilities with shape (N, 2)
    if preds.shape[1] == 2:
        pos_probs = preds[:, 1]
    else:
        # If single-probability column (positive class)
        pos_probs = preds[:, -1]
    y_pred = (pos_probs >= 0.5).astype(int)
else:
    # Already class labels
    y_pred = preds.astype(int)
    pos_probs = None

# Ground truth labels (must be 0/1 integers)
y_true = test_data["label"].astype(int).to_numpy()

# Core metrics
metrics = {}
metrics["accuracy"] = accuracy_score(y_true, y_pred)
metrics["precision"] = precision_score(y_true, y_pred, zero_division=0)
metrics["recall"] = recall_score(y_true, y_pred, zero_division=0)
metrics["f1"] = f1_score(y_true, y_pred, zero_division=0)
metrics["mcc"] = matthews_corrcoef(y_true, y_pred)

# Probabilistic metrics (only if we have probabilities)
if pos_probs is not None:
    metrics["roc_auc"] = roc_auc_score(y_true, pos_probs)
    metrics["pr_auc"] = average_precision_score(y_true, pos_probs)
    metrics["log_loss"] = log_loss(y_true, pos_probs, labels=[0,1])
    metrics["brier_score"] = brier_score_loss(y_true, pos_probs)

# Confusion matrix and detailed report
cm = confusion_matrix(y_true, y_pred, labels=[0,1])
report = classification_report(y_true, y_pred, digits=4)

print("Sklearn binary metrics:")
for k, v in metrics.items():
    print(f"{k}: {v:.4f}")
print("\nConfusion matrix:\n", cm)
print("\nClassification report:\n", report)
# Out:
#  1/91 [..............................] - ETA: 9s
#  3/91 [..............................] - ETA: 3s
#  4/91 [>.............................] - ETA: 4s
#  6/91 [>.............................] - ETA: 3s
#  8/91 [=>............................] - ETA: 3s
# 10/91 [==>...........................] - ETA: 3s
# 12/91 [==>...........................] - ETA: 3s
# 14/91 [===>..........................] - ETA: 3s
# 16/91 [====>.........................] - ETA: 3s
# 18/91 [====>.........................] - ETA: 3s
# 20/91 [=====>........................] - ETA: 2s
# 22/91 [======>.......................] - ETA: 2s
# 24/91 [======>.......................] - ETA: 2s
# 26/91 [=======>......................] - ETA: 2s
# 28/91 [========>.....................] - ETA: 2s
# 30/91 [========>.....................] - ETA: 2s
# 32/91 [=========>....................] - ETA: 2s
# 34/91 [==========>...................] - ETA: 2s
# 36/91 [==========>...................] - ETA: 2s
# 38/91 [===========>..................] - ETA: 2s
# 40/91 [============>.................] - ETA: 2s
# 42/91 [============>.................] - ETA: 1s
# 44/91 [=============>................] - ETA: 1s
# 46/91 [==============>...............] - ETA: 1s
# 48/91 [==============>...............] - ETA: 1s
# 50/91 [===============>..............] - ETA: 1s
# 52/91 [================>.............] - ETA: 1s
# 54/91 [================>.............] - ETA: 1s
# 56/91 [=================>............] - ETA: 1s
# 58/91 [==================>...........] - ETA: 1s
# 60/91 [==================>...........] - ETA: 1s
# 62/91 [===================>..........] - ETA: 1s
# 64/91 [====================>.........] - ETA: 1s
# 66/91 [====================>.........] - ETA: 1s
# 68/91 [=====================>........] - ETA: 0s
# 69/91 [=====================>........] - ETA: 0s
# 70/91 [======================>.......] - ETA: 0s
# 72/91 [======================>.......] - ETA: 0s
# 74/91 [=======================>......] - ETA: 0s
# 76/91 [========================>.....] - ETA: 0s
# 78/91 [========================>.....] - ETA: 0s
# 80/91 [=========================>....] - ETA: 0s
# 82/91 [==========================>...] - ETA: 0s
# 84/91 [==========================>...] - ETA: 0s
# 86/91 [===========================>..] - ETA: 0s
# 88/91 [============================>.] - ETA: 0s
# 90/91 [============================>.] - ETA: 0s
# 91/91 [==============================] - 4s 41ms/step
# Sklearn binary metrics:
# accuracy: 0.9086
# precision: 0.3914
# recall: 0.7733
# f1: 0.5197
# mcc: 0.5090
# roc_auc: 0.9351
# pr_auc: 0.5444
# log_loss: 0.2442
# brier_score: 0.0684
#
# Confusion matrix:
#  [[77432  6927]
#  [ 1306  4455]]
#
# Classification report:
#                precision    recall  f1-score   support
#
#            0     0.9834    0.9179    0.9495     84359
#            1     0.3914    0.7733    0.5197      5761
#
#     accuracy                         0.9086     90120
#    macro avg     0.6874    0.8456    0.7346     90120
# weighted avg     0.9456    0.9086    0.9220     90120
