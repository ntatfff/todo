# %%
# Import packages and modules
import numpy  as np
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow_decision_forests as tfdf

from sklearn.model_selection import train_test_split
# Out:
# 2026-07-04 08:34:59.896888: I tensorflow/core/util/port.cc:113] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2026-07-04 08:34:59.953209: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2026-07-04 08:35:04.167164: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
# Check the version of TensorFlow Decision Forests
print("Found TensorFlow Decision Forests v" + tfdf.__version__)
# Out:
# Found TensorFlow Decision Forests v1.9.1

# %%
datasetPath = 'dataset/firstorder/kernel5-radius5/dataset.csv'

# %%
# Parameters
datasetPath = "dataset/gldm/kernel5-radius5/300.dataset.csv"

# %%
# train/validation/test = 70/10/20
dataset = pd.read_csv(datasetPath)

train_data, temp_data = train_test_split(dataset, test_size=0.3, random_state=42)
validation_data, test_data = train_test_split(temp_data, test_size=2/3, random_state=42)

# %%
from sklearn.utils.class_weight import compute_class_weight

# tinh class weight tren tap train
classes = np.array([0, 1])
weights = compute_class_weight(class_weight="balanced", classes=classes, y=train_data["label"])
class_weight = {0: weights[0], 1: weights[1]}

# gan sample_weight cho tung dong
train_data["sample_weight"] = train_data["label"].map(class_weight)
validation_data["sample_weight"] = validation_data["label"].map(class_weight)
test_data["sample_weight"] = test_data["label"].map(class_weight)

# Convert the dataset into a TensorFlow dataset.
train_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    train_data, label="label", weight="sample_weight"
)         
val_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    validation_data, label="label", weight="sample_weight"
)
test_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    test_data, label="label", weight="sample_weight"
)
# Out:
# 2026-07-04 08:35:16.309197: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:984] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2026-07-04 08:35:16.310767: W tensorflow/core/common_runtime/gpu/gpu_device.cc:2251] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...

# %%
import keras

# %%
# %%time

# Train a Gradient Boosted Trees model.
model = tfdf.keras.GradientBoostedTreesModel()

# Add evaluation metrics
model.compile(
    metrics=["accuracy"]
)
model.fit(x=train_ds)

# # Train a Gradient Boosted Trees model.
# model = tfdf.keras.GradientBoostedTreesModel(num_trees=1500)
# model.fit(train_ds)
# Out:
# Use /tmp/tmplkrtanow as temporary training directory
# Reading training dataset...
# [WARNING 26-07-04 08:35:16.4589 UTC gradient_boosted_trees.cc:1840] "goss_alpha" set but "sampling_method" not equal to "GOSS".
# [WARNING 26-07-04 08:35:16.4590 UTC gradient_boosted_trees.cc:1851] "goss_beta" set but "sampling_method" not equal to "GOSS".
# [WARNING 26-07-04 08:35:16.4590 UTC gradient_boosted_trees.cc:1865] "selective_gradient_boosting_ratio" set but "sampling_method" not equal to "SELGB".
# Training dataset read in 0:00:03.999453. Found 235709 examples.
# Training model...
# Model trained in 0:00:51.107648
# Compiling model...
# [INFO 26-07-04 08:36:11.5805 UTC kernel.cc:1233] Loading model from path /tmp/tmplkrtanow/model/ with prefix f61684fba0dd4951
# [INFO 26-07-04 08:36:11.5919 UTC quick_scorer_extended.cc:911] The binary was compiled without AVX2 support, but your CPU supports it. Enable it for faster model inference.
# [INFO 26-07-04 08:36:11.5927 UTC abstract_model.cc:1362] Engine "GradientBoostedTreesQuickScorerExtended" built
# [INFO 26-07-04 08:36:11.5927 UTC kernel.cc:1061] Use fast generic engine
# Model compiled.
# CPU times: user 6min 2s, sys: 3.28 s, total: 6min 5s
# Wall time: 58.2 s

# %%
# Evaluate the model
evaluate = model.evaluate(val_ds, return_dict=True)
print()

for name, value in evaluate.items():
    print(f"{name}: {value:.4f}")
# Out:
# WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
#  1/34 [..............................] - ETA: 1:37 - loss: 0.0000e+00 - accuracy: 0.9260
# 14/34 [===========>..................] - ETA: 0s - loss: 0.0000e+00 - accuracy: 0.8972
# 27/34 [======================>.......] - ETA: 0s - loss: 0.0000e+00 - accuracy: 0.8994
# 34/34 [==============================] - 3s 4ms/step - loss: 0.0000e+00 - accuracy: 0.8994
# loss: 0.0000
# accuracy: 0.8994

# %%
# Model Summary
model.summary()
# Out:
# Model: "gradient_boosted_trees_model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
# =================================================================
# Total params: 1 (1.00 Byte)
# Trainable params: 0 (0.00 Byte)
# Non-trainable params: 1 (1.00 Byte)
# _________________________________________________________________
# Type: "GRADIENT_BOOSTED_TREES"
# Task: CLASSIFICATION
# Label: "__LABEL"
#
# Input Features (14):
# 	DependenceEntropy
# 	DependenceNonUniformity
# 	DependenceNonUniformityNormalized
# 	DependenceVariance
# 	GrayLevelNonUniformity
# 	GrayLevelVariance
# 	HighGrayLevelEmphasis
# 	LargeDependenceEmphasis
# 	LargeDependenceHighGrayLevelEmphasis
# 	LargeDependenceLowGrayLevelEmphasis
# 	LowGrayLevelEmphasis
# 	SmallDependenceEmphasis
# 	SmallDependenceHighGrayLevelEmphasis
# 	SmallDependenceLowGrayLevelEmphasis
#
# Trained with weights
#
# Variable Importance: INV_MEAN_MIN_DEPTH:
#     1. "LargeDependenceHighGrayLevelEmphasis"  0.251758 ################
#     2.                    "DependenceEntropy"  0.222895 #########
#     3.  "SmallDependenceLowGrayLevelEmphasis"  0.219164 #########
#     4.                "HighGrayLevelEmphasis"  0.215235 ########
#     5.               "GrayLevelNonUniformity"  0.207174 ######
#     6.              "SmallDependenceEmphasis"  0.206807 ######
#     7.                    "GrayLevelVariance"  0.203286 #####
#     8.                 "LowGrayLevelEmphasis"  0.201880 #####
#     9. "SmallDependenceHighGrayLevelEmphasis"  0.200209 #####
#    10.  "LargeDependenceLowGrayLevelEmphasis"  0.189225 ##
#    11.                   "DependenceVariance"  0.186337 ##
#    12.              "LargeDependenceEmphasis"  0.178930
#    13.              "DependenceNonUniformity"  0.175736
#    14.    "DependenceNonUniformityNormalized"  0.175379
#
# Variable Importance: NUM_AS_ROOT:
#     1. "LargeDependenceHighGrayLevelEmphasis" 52.000000 ################
#     2.                "HighGrayLevelEmphasis" 34.000000 ##########
#     3.                    "DependenceEntropy" 29.000000 ########
#     4.               "GrayLevelNonUniformity" 26.000000 #######
#     5.                 "LowGrayLevelEmphasis" 25.000000 #######
#     6.  "SmallDependenceLowGrayLevelEmphasis" 23.000000 ######
#     7.                    "GrayLevelVariance" 19.000000 #####
#     8.                   "DependenceVariance"  8.000000 ##
#     9.              "SmallDependenceEmphasis"  7.000000 #
#    10.  "LargeDependenceLowGrayLevelEmphasis"  6.000000 #
#    11. "SmallDependenceHighGrayLevelEmphasis"  5.000000 #
#    12.              "LargeDependenceEmphasis"  2.000000
#    13.    "DependenceNonUniformityNormalized"  1.000000
#
# Variable Importance: NUM_NODES:
#     1. "LargeDependenceHighGrayLevelEmphasis" 744.000000 ################
#     2.                    "DependenceEntropy" 669.000000 ##############
#     3.  "SmallDependenceLowGrayLevelEmphasis" 645.000000 #############
#     4. "SmallDependenceHighGrayLevelEmphasis" 586.000000 ############
#     5.                "HighGrayLevelEmphasis" 546.000000 ###########
#     6.              "SmallDependenceEmphasis" 527.000000 ##########
#     7.                    "GrayLevelVariance" 508.000000 ##########
#     8.               "GrayLevelNonUniformity" 482.000000 #########
#     9.                 "LowGrayLevelEmphasis" 376.000000 ######
#    10.  "LargeDependenceLowGrayLevelEmphasis" 353.000000 ######
#    11.                   "DependenceVariance" 305.000000 ####
#    12.              "LargeDependenceEmphasis" 176.000000 #
#    13.              "DependenceNonUniformity" 135.000000
#    14.    "DependenceNonUniformityNormalized" 109.000000
#
# Variable Importance: SUM_SCORE:
#     1.                "HighGrayLevelEmphasis" 89141.128210 ################
#     2.                    "DependenceEntropy" 31587.389905 #####
#     3. "LargeDependenceHighGrayLevelEmphasis" 20689.588041 ###
#     4. "SmallDependenceHighGrayLevelEmphasis" 19325.867190 ###
#     5.  "SmallDependenceLowGrayLevelEmphasis" 17338.795570 ###
#     6.                 "LowGrayLevelEmphasis" 10762.953803 #
#     7.               "GrayLevelNonUniformity" 6734.991971 #
#     8.              "SmallDependenceEmphasis" 5783.967486
#     9.                    "GrayLevelVariance" 3790.166867
#    10.                   "DependenceVariance" 2514.207358
#    11.  "LargeDependenceLowGrayLevelEmphasis" 1682.562651
#    12.              "LargeDependenceEmphasis" 1112.092832
#    13.              "DependenceNonUniformity" 393.814059
#    14.    "DependenceNonUniformityNormalized" 372.868724
#
#
#
# Loss: BINOMIAL_LOG_LIKELIHOOD
# Validation loss value: 0.519543
# Number of trees per iteration: 1
# Node format: NOT_SET
# Number of trees: 237
# Total number of nodes: 12559
#
# Number of nodes by tree:
# Count: 237 Average: 52.9916 StdDev: 8.03263
# Min: 31 Max: 63 Ignored: 0
# ----------------------------------------------
# [ 31, 32)  1   0.42%   0.42%
# [ 32, 34)  0   0.00%   0.42%
# [ 34, 35)  0   0.00%   0.42%
# [ 35, 37)  5   2.11%   2.53% #
# [ 37, 39)  4   1.69%   4.22% #
# [ 39, 40)  7   2.95%   7.17% ##
# [ 40, 42) 10   4.22%  11.39% ###
# [ 42, 44) 10   4.22%  15.61% ###
# [ 44, 45)  0   0.00%  15.61%
# [ 45, 47)  9   3.80%  19.41% ##
# [ 47, 49) 16   6.75%  26.16% ####
# [ 49, 50) 30  12.66%  38.82% ########
# [ 50, 52) 15   6.33%  45.15% ####
# [ 52, 54) 15   6.33%  51.48% ####
# [ 54, 55)  0   0.00%  51.48%
# [ 55, 57) 16   6.75%  58.23% ####
# [ 57, 59) 17   7.17%  65.40% ####
# [ 59, 60) 13   5.49%  70.89% ###
# [ 60, 62) 29  12.24%  83.12% #######
# [ 62, 63] 40  16.88% 100.00% ##########
#
# Depth by leafs:
# Count: 6398 Average: 4.87324 StdDev: 0.458363
# Min: 2 Max: 5 Ignored: 0
# ----------------------------------------------
# [ 2, 3)   57   0.89%   0.89%
# [ 3, 4)  147   2.30%   3.19%
# [ 4, 5)  346   5.41%   8.60% #
# [ 5, 5] 5848  91.40% 100.00% ##########
#
# Number of training obs by leaf:
# Count: 6398 Average: 7854.34 StdDev: 26965.6
# Min: 5 Max: 209685 Ignored: 0
# ----------------------------------------------
# [      5,  10489) 5638  88.12%  88.12% ##########
# [  10489,  20973)  272   4.25%  92.37%
# [  20973,  31457)  121   1.89%  94.26%
# [  31457,  41941)   50   0.78%  95.05%
# [  41941,  52425)   50   0.78%  95.83%
# [  52425,  62909)   36   0.56%  96.39%
# [  62909,  73393)   33   0.52%  96.91%
# [  73393,  83877)   12   0.19%  97.09%
# [  83877,  94361)   15   0.23%  97.33%
# [  94361, 104845)   21   0.33%  97.66%
# [ 104845, 115329)   10   0.16%  97.81%
# [ 115329, 125813)   10   0.16%  97.97%
# [ 125813, 136297)   13   0.20%  98.17%
# [ 136297, 146781)   13   0.20%  98.37%
# [ 146781, 157265)   19   0.30%  98.67%
# [ 157265, 167749)   22   0.34%  99.02%
# [ 167749, 178233)   19   0.30%  99.31%
# [ 178233, 188717)   14   0.22%  99.53%
# [ 188717, 199201)   18   0.28%  99.81%
# [ 199201, 209685]   12   0.19% 100.00%
#
# Attribute in nodes:
# 	744 : LargeDependenceHighGrayLevelEmphasis [NUMERICAL]
# 	669 : DependenceEntropy [NUMERICAL]
# 	645 : SmallDependenceLowGrayLevelEmphasis [NUMERICAL]
# 	586 : SmallDependenceHighGrayLevelEmphasis [NUMERICAL]
# 	546 : HighGrayLevelEmphasis [NUMERICAL]
# 	527 : SmallDependenceEmphasis [NUMERICAL]
# 	508 : GrayLevelVariance [NUMERICAL]
# 	482 : GrayLevelNonUniformity [NUMERICAL]
# 	376 : LowGrayLevelEmphasis [NUMERICAL]
# 	353 : LargeDependenceLowGrayLevelEmphasis [NUMERICAL]
# 	305 : DependenceVariance [NUMERICAL]
# 	176 : LargeDependenceEmphasis [NUMERICAL]
# 	135 : DependenceNonUniformity [NUMERICAL]
# 	109 : DependenceNonUniformityNormalized [NUMERICAL]
#
# Attribute in nodes with depth <= 0:
# 	52 : LargeDependenceHighGrayLevelEmphasis [NUMERICAL]
# 	34 : HighGrayLevelEmphasis [NUMERICAL]
# 	29 : DependenceEntropy [NUMERICAL]
# 	26 : GrayLevelNonUniformity [NUMERICAL]
# 	25 : LowGrayLevelEmphasis [NUMERICAL]
# 	23 : SmallDependenceLowGrayLevelEmphasis [NUMERICAL]
# 	19 : GrayLevelVariance [NUMERICAL]
# 	8 : DependenceVariance [NUMERICAL]
# 	7 : SmallDependenceEmphasis [NUMERICAL]
# 	6 : LargeDependenceLowGrayLevelEmphasis [NUMERICAL]
# 	5 : SmallDependenceHighGrayLevelEmphasis [NUMERICAL]
# 	2 : LargeDependenceEmphasis [NUMERICAL]
# 	1 : DependenceNonUniformityNormalized [NUMERICAL]
#
# Attribute in nodes with depth <= 1:
# 	127 : LargeDependenceHighGrayLevelEmphasis [NUMERICAL]
# 	85 : SmallDependenceLowGrayLevelEmphasis [NUMERICAL]
# 	80 : DependenceEntropy [NUMERICAL]
# 	66 : SmallDependenceEmphasis [NUMERICAL]
# 	62 : HighGrayLevelEmphasis [NUMERICAL]
# 	60 : GrayLevelNonUniformity [NUMERICAL]
# 	56 : GrayLevelVariance [NUMERICAL]
# 	54 : LowGrayLevelEmphasis [NUMERICAL]
# 	51 : SmallDependenceHighGrayLevelEmphasis [NUMERICAL]
# 	31 : LargeDependenceLowGrayLevelEmphasis [NUMERICAL]
# 	21 : DependenceVariance [NUMERICAL]
# 	14 : LargeDependenceEmphasis [NUMERICAL]
# 	2 : DependenceNonUniformityNormalized [NUMERICAL]
# 	2 : DependenceNonUniformity [NUMERICAL]
#
# Attribute in nodes with depth <= 2:
# 	220 : LargeDependenceHighGrayLevelEmphasis [NUMERICAL]
# 	174 : SmallDependenceLowGrayLevelEmphasis [NUMERICAL]
# 	171 : DependenceEntropy [NUMERICAL]
# 	148 : SmallDependenceEmphasis [NUMERICAL]
# 	145 : HighGrayLevelEmphasis [NUMERICAL]
# 	140 : SmallDependenceHighGrayLevelEmphasis [NUMERICAL]
# 	127 : GrayLevelNonUniformity [NUMERICAL]
# 	125 : GrayLevelVariance [NUMERICAL]
# 	100 : LowGrayLevelEmphasis [NUMERICAL]
# 	92 : LargeDependenceLowGrayLevelEmphasis [NUMERICAL]
# 	72 : DependenceVariance [NUMERICAL]
# 	38 : LargeDependenceEmphasis [NUMERICAL]
# 	26 : DependenceNonUniformity [NUMERICAL]
# 	24 : DependenceNonUniformityNormalized [NUMERICAL]
#
# Attribute in nodes with depth <= 3:
# 	412 : LargeDependenceHighGrayLevelEmphasis [NUMERICAL]
# 	365 : SmallDependenceLowGrayLevelEmphasis [NUMERICAL]
# 	327 : DependenceEntropy [NUMERICAL]
# 	317 : SmallDependenceHighGrayLevelEmphasis [NUMERICAL]
# 	300 : SmallDependenceEmphasis [NUMERICAL]
# 	268 : HighGrayLevelEmphasis [NUMERICAL]
# 	262 : GrayLevelVariance [NUMERICAL]
# 	242 : GrayLevelNonUniformity [NUMERICAL]
# 	193 : LowGrayLevelEmphasis [NUMERICAL]
# 	185 : LargeDependenceLowGrayLevelEmphasis [NUMERICAL]
# 	157 : DependenceVariance [NUMERICAL]
# 	90 : LargeDependenceEmphasis [NUMERICAL]
# 	69 : DependenceNonUniformity [NUMERICAL]
# 	50 : DependenceNonUniformityNormalized [NUMERICAL]
#
# Attribute in nodes with depth <= 5:
# 	744 : LargeDependenceHighGrayLevelEmphasis [NUMERICAL]
# 	669 : DependenceEntropy [NUMERICAL]
# 	645 : SmallDependenceLowGrayLevelEmphasis [NUMERICAL]
# 	586 : SmallDependenceHighGrayLevelEmphasis [NUMERICAL]
# 	546 : HighGrayLevelEmphasis [NUMERICAL]
# 	527 : SmallDependenceEmphasis [NUMERICAL]
# 	508 : GrayLevelVariance [NUMERICAL]
# 	482 : GrayLevelNonUniformity [NUMERICAL]
# 	376 : LowGrayLevelEmphasis [NUMERICAL]
# 	353 : LargeDependenceLowGrayLevelEmphasis [NUMERICAL]
# 	305 : DependenceVariance [NUMERICAL]
# 	176 : LargeDependenceEmphasis [NUMERICAL]
# 	135 : DependenceNonUniformity [NUMERICAL]
# 	109 : DependenceNonUniformityNormalized [NUMERICAL]
#
# Condition type in nodes:
# 	6161 : HigherCondition
# Condition type in nodes with depth <= 0:
# 	237 : HigherCondition
# Condition type in nodes with depth <= 1:
# 	711 : HigherCondition
# Condition type in nodes with depth <= 2:
# 	1602 : HigherCondition
# Condition type in nodes with depth <= 3:
# 	3237 : HigherCondition
# Condition type in nodes with depth <= 5:
# 	6161 : HigherCondition
#
# Training logs:
# Number of iteration to final model: 237
# 	Iter:1 train-loss:1.276734 valid-loss:1.277052  train-accuracy:0.847770 valid-accuracy:0.840164
# 	Iter:2 train-loss:1.186319 valid-loss:1.188577  train-accuracy:0.851813 valid-accuracy:0.844561
# 	Iter:3 train-loss:1.112024 valid-loss:1.115101  train-accuracy:0.857715 valid-accuracy:0.850051
# 	Iter:4 train-loss:1.047025 valid-loss:1.050907  train-accuracy:0.858078 valid-accuracy:0.850766
# 	Iter:5 train-loss:0.991466 valid-loss:0.995710  train-accuracy:0.859936 valid-accuracy:0.851904
# 	Iter:6 train-loss:0.942164 valid-loss:0.946282  train-accuracy:0.867423 valid-accuracy:0.860995
# 	Iter:16 train-loss:0.681687 valid-loss:0.689527  train-accuracy:0.882377 valid-accuracy:0.876711
# 	Iter:26 train-loss:0.589144 valid-loss:0.603009  train-accuracy:0.888091 valid-accuracy:0.883493
# 	Iter:36 train-loss:0.549698 valid-loss:0.569514  train-accuracy:0.891652 valid-accuracy:0.884058
# 	Iter:46 train-loss:0.528589 valid-loss:0.553131  train-accuracy:0.893442 valid-accuracy:0.883494
# 	Iter:56 train-loss:0.514539 valid-loss:0.544383  train-accuracy:0.896083 valid-accuracy:0.884281
# 	Iter:66 train-loss:0.503248 valid-loss:0.538799  train-accuracy:0.898022 valid-accuracy:0.886129
# 	Iter:76 train-loss:0.495016 valid-loss:0.534966  train-accuracy:0.899423 valid-accuracy:0.887299
# 	Iter:86 train-loss:0.488558 valid-loss:0.533525  train-accuracy:0.900436 valid-accuracy:0.887436
# 	Iter:96 train-loss:0.481121 valid-loss:0.530263  train-accuracy:0.901824 valid-accuracy:0.887759
# 	Iter:106 train-loss:0.475348 valid-loss:0.529578  train-accuracy:0.903003 valid-accuracy:0.887536
# 	Iter:116 train-loss:0.470459 valid-loss:0.528188  train-accuracy:0.904027 valid-accuracy:0.887609
# 	Iter:126 train-loss:0.466241 valid-loss:0.526976  train-accuracy:0.904961 valid-accuracy:0.889047
# 	Iter:136 train-loss:0.461990 valid-loss:0.525106  train-accuracy:0.905809 valid-accuracy:0.889762
# 	Iter:146 train-loss:0.457348 valid-loss:0.524815  train-accuracy:0.907246 valid-accuracy:0.889007
# 	Iter:156 train-loss:0.453372 valid-loss:0.523703  train-accuracy:0.908300 valid-accuracy:0.889134
# 	Iter:166 train-loss:0.449430 valid-loss:0.522738  train-accuracy:0.909520 valid-accuracy:0.889940
# 	Iter:176 train-loss:0.445114 valid-loss:0.522234  train-accuracy:0.910088 valid-accuracy:0.889284
# 	Iter:186 train-loss:0.441658 valid-loss:0.521317  train-accuracy:0.910879 valid-accuracy:0.889999
# 	Iter:196 train-loss:0.437582 valid-loss:0.520380  train-accuracy:0.911686 valid-accuracy:0.889266
# 	Iter:206 train-loss:0.433434 valid-loss:0.520033  train-accuracy:0.912865 valid-accuracy:0.888998
# 	Iter:216 train-loss:0.430675 valid-loss:0.520346  train-accuracy:0.913373 valid-accuracy:0.889057
# 	Iter:226 train-loss:0.427088 valid-loss:0.519726  train-accuracy:0.914750 valid-accuracy:0.888934
# 	Iter:236 train-loss:0.423934 valid-loss:0.519675  train-accuracy:0.915338 valid-accuracy:0.888438
# 	Iter:246 train-loss:0.421536 valid-loss:0.520558  train-accuracy:0.916065 valid-accuracy:0.888201
# 	Iter:256 train-loss:0.418982 valid-loss:0.520599  train-accuracy:0.916834 valid-accuracy:0.887796
# 	Iter:266 train-loss:0.416022 valid-loss:0.520635  train-accuracy:0.917772 valid-accuracy:0.888351

# %%
# Model features
model.make_inspector().features()
# Out:
# ["DependenceEntropy" (1; #0),
#  "DependenceNonUniformity" (1; #1),
#  "DependenceNonUniformityNormalized" (1; #2),
#  "DependenceVariance" (1; #3),
#  "GrayLevelNonUniformity" (1; #4),
#  "GrayLevelVariance" (1; #5),
#  "HighGrayLevelEmphasis" (1; #6),
#  "LargeDependenceEmphasis" (1; #7),
#  "LargeDependenceHighGrayLevelEmphasis" (1; #8),
#  "LargeDependenceLowGrayLevelEmphasis" (1; #9),
#  "LowGrayLevelEmphasis" (1; #10),
#  "SmallDependenceEmphasis" (1; #11),
#  "SmallDependenceHighGrayLevelEmphasis" (1; #12),
#  "SmallDependenceLowGrayLevelEmphasis" (1; #13)]

# %%
# Feature importance
model.make_inspector().variable_importances()
# Out:
# {'INV_MEAN_MIN_DEPTH': [("LargeDependenceHighGrayLevelEmphasis" (1; #8),
#    0.25175836164273596),
#   ("DependenceEntropy" (1; #0), 0.22289460979739945),
#   ("SmallDependenceLowGrayLevelEmphasis" (1; #13), 0.21916379568071864),
#   ("HighGrayLevelEmphasis" (1; #6), 0.215235054299156),
#   ("GrayLevelNonUniformity" (1; #4), 0.2071744301331326),
#   ("SmallDependenceEmphasis" (1; #11), 0.20680679599773968),
#   ("GrayLevelVariance" (1; #5), 0.20328574383040782),
#   ("LowGrayLevelEmphasis" (1; #10), 0.20188028026954907),
#   ("SmallDependenceHighGrayLevelEmphasis" (1; #12), 0.20020915519503904),
#   ("LargeDependenceLowGrayLevelEmphasis" (1; #9), 0.18922491712854345),
#   ("DependenceVariance" (1; #3), 0.18633714249048028),
#   ("LargeDependenceEmphasis" (1; #7), 0.1789296643085651),
#   ("DependenceNonUniformity" (1; #1), 0.17573555563203075),
#   ("DependenceNonUniformityNormalized" (1; #2), 0.17537934057630017)],
#  'NUM_AS_ROOT': [("LargeDependenceHighGrayLevelEmphasis" (1; #8), 52.0),
#   ("HighGrayLevelEmphasis" (1; #6), 34.0),
#   ("DependenceEntropy" (1; #0), 29.0),
#   ("GrayLevelNonUniformity" (1; #4), 26.0),
#   ("LowGrayLevelEmphasis" (1; #10), 25.0),
#   ("SmallDependenceLowGrayLevelEmphasis" (1; #13), 23.0),
#   ("GrayLevelVariance" (1; #5), 19.0),
#   ("DependenceVariance" (1; #3), 8.0),
#   ("SmallDependenceEmphasis" (1; #11), 7.0),
#   ("LargeDependenceLowGrayLevelEmphasis" (1; #9), 6.0),
#   ("SmallDependenceHighGrayLevelEmphasis" (1; #12), 5.0),
#   ("LargeDependenceEmphasis" (1; #7), 2.0),
#   ("DependenceNonUniformityNormalized" (1; #2), 1.0)],
#  'SUM_SCORE': [("HighGrayLevelEmphasis" (1; #6), 89141.12820998569),
#   ("DependenceEntropy" (1; #0), 31587.389904820935),
#   ("LargeDependenceHighGrayLevelEmphasis" (1; #8), 20689.58804119936),
#   ("SmallDependenceHighGrayLevelEmphasis" (1; #12), 19325.8671901626),
#   ("SmallDependenceLowGrayLevelEmphasis" (1; #13), 17338.795569964248),
#   ("LowGrayLevelEmphasis" (1; #10), 10762.953803006534),
#   ("GrayLevelNonUniformity" (1; #4), 6734.991970542136),
#   ("SmallDependenceEmphasis" (1; #11), 5783.967486373156),
#   ("GrayLevelVariance" (1; #5), 3790.1668673090176),
#   ("DependenceVariance" (1; #3), 2514.207357617756),
#   ("LargeDependenceLowGrayLevelEmphasis" (1; #9), 1682.5626506675414),
#   ("LargeDependenceEmphasis" (1; #7), 1112.0928317578207),
#   ("DependenceNonUniformity" (1; #1), 393.81405935235244),
#   ("DependenceNonUniformityNormalized" (1; #2), 372.8687243637012)],
#  'NUM_NODES': [("LargeDependenceHighGrayLevelEmphasis" (1; #8), 744.0),
#   ("DependenceEntropy" (1; #0), 669.0),
#   ("SmallDependenceLowGrayLevelEmphasis" (1; #13), 645.0),
#   ("SmallDependenceHighGrayLevelEmphasis" (1; #12), 586.0),
#   ("HighGrayLevelEmphasis" (1; #6), 546.0),
#   ("SmallDependenceEmphasis" (1; #11), 527.0),
#   ("GrayLevelVariance" (1; #5), 508.0),
#   ("GrayLevelNonUniformity" (1; #4), 482.0),
#   ("LowGrayLevelEmphasis" (1; #10), 376.0),
#   ("LargeDependenceLowGrayLevelEmphasis" (1; #9), 353.0),
#   ("DependenceVariance" (1; #3), 305.0),
#   ("LargeDependenceEmphasis" (1; #7), 176.0),
#   ("DependenceNonUniformity" (1; #1), 135.0),
#   ("DependenceNonUniformityNormalized" (1; #2), 109.0)]}

# %%
# Model self evaluation
model.make_inspector().evaluation()
# Out:
# Evaluation(num_examples=None, accuracy=0.8885061740875244, loss=0.5195432901382446, rmse=None, ndcg=None, aucs=None, auuc=None, qini=None)

# %%
logs = model.make_inspector().training_logs()

plt.figure(figsize=(12, 4))
plt.subplot(1, 2, 1)
plt.plot([log.num_trees for log in logs], [log.evaluation.accuracy for log in logs])
plt.xlabel("Number of trees")
plt.ylabel("Accuracy (out-of-bag)")
plt.subplot(1, 2, 2)
plt.plot([log.num_trees for log in logs], [log.evaluation.loss for log in logs])
plt.xlabel("Number of trees")
plt.ylabel("Logloss (out-of-bag)")
plt.show()

# %% [markdown]
# Calculate the score of our hold-out validation dataset

# %%
predictions = model.predict(val_ds)
y_true      = validation_data["label"]

from sklearn.metrics import roc_auc_score
ROC_AUC = roc_auc_score(y_true, predictions)
print("The ROC AUC score is %.5f" % ROC_AUC )
# Out:
#  1/34 [..............................] - ETA: 1s
# 14/34 [===========>..................] - ETA: 0s
# 25/34 [=====================>........] - ETA: 0s
# 34/34 [==============================] - 0s 4ms/step
# The ROC AUC score is 0.95954

# %%
# Compute binary classification metrics with sklearn
import numpy as np
from sklearn.metrics import (
    accuracy_score,
    precision_score,
    recall_score,
    f1_score,
    roc_auc_score,
    average_precision_score,
    confusion_matrix,
    classification_report,
    matthews_corrcoef,
    log_loss,
    brier_score_loss,
)

# Get predictions (probabilities or class labels)
preds = model.predict(test_ds)
# If model outputs probabilities, convert to labels by threshold 0.5
if preds.ndim == 2:
    # For TFDF classification, preds may be class probabilities with shape (N, 2)
    if preds.shape[1] == 2:
        pos_probs = preds[:, 1]
    else:
        # If single-probability column (positive class)
        pos_probs = preds[:, -1]
    y_pred = (pos_probs >= 0.5).astype(int)
else:
    # Already class labels
    y_pred = preds.astype(int)
    pos_probs = None

# Ground truth labels (must be 0/1 integers)
y_true = test_data["label"].astype(int).to_numpy()

# Core metrics
metrics = {}
metrics["accuracy"] = accuracy_score(y_true, y_pred)
metrics["precision"] = precision_score(y_true, y_pred, zero_division=0)
metrics["recall"] = recall_score(y_true, y_pred, zero_division=0)
metrics["f1"] = f1_score(y_true, y_pred, zero_division=0)
metrics["mcc"] = matthews_corrcoef(y_true, y_pred)

# Probabilistic metrics (only if we have probabilities)
if pos_probs is not None:
    metrics["roc_auc"] = roc_auc_score(y_true, pos_probs)
    metrics["pr_auc"] = average_precision_score(y_true, pos_probs)
    metrics["log_loss"] = log_loss(y_true, pos_probs, labels=[0,1])
    metrics["brier_score"] = brier_score_loss(y_true, pos_probs)

# Confusion matrix and detailed report
cm = confusion_matrix(y_true, y_pred, labels=[0,1])
report = classification_report(y_true, y_pred, digits=4)

print("Sklearn binary metrics:")
for k, v in metrics.items():
    print(f"{k}: {v:.4f}")
print("\nConfusion matrix:\n", cm)
print("\nClassification report:\n", report)
# Out:
#  1/68 [..............................] - ETA: 4s
# 14/68 [=====>........................] - ETA: 0s
# 28/68 [===========>..................] - ETA: 0s
# 41/68 [=================>............] - ETA: 0s
# 55/68 [=======================>......] - ETA: 0s
# 68/68 [==============================] - 0s 4ms/step
# Sklearn binary metrics:
# accuracy: 0.8972
# precision: 0.3587
# recall: 0.8702
# f1: 0.5080
# mcc: 0.5184
# roc_auc: 0.9565
# pr_auc: 0.7008
# log_loss: 0.2454
# brier_score: 0.0749
#
# Confusion matrix:
#  [[56854  6387]
#  [  533  3572]]
#
# Classification report:
#                precision    recall  f1-score   support
#
#            0     0.9907    0.8990    0.9426     63241
#            1     0.3587    0.8702    0.5080      4105
#
#     accuracy                         0.8972     67346
#    macro avg     0.6747    0.8846    0.7253     67346
# weighted avg     0.9522    0.8972    0.9161     67346
