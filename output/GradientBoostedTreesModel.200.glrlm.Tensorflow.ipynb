# %%
# Import packages and modules
import numpy  as np
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow_decision_forests as tfdf

from sklearn.model_selection import train_test_split
# Out:
# 2026-07-04 08:47:12.381675: I tensorflow/core/util/port.cc:113] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2026-07-04 08:47:12.421190: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2026-07-04 08:47:16.664658: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
# Check the version of TensorFlow Decision Forests
print("Found TensorFlow Decision Forests v" + tfdf.__version__)
# Out:
# Found TensorFlow Decision Forests v1.9.1

# %%
datasetPath = 'dataset/firstorder/kernel5-radius5/dataset.csv'

# %%
# Parameters
datasetPath = "dataset/glrlm/kernel5-radius5/200.dataset.csv"

# %%
# train/validation/test = 70/10/20
dataset = pd.read_csv(datasetPath)

train_data, temp_data = train_test_split(dataset, test_size=0.3, random_state=42)
validation_data, test_data = train_test_split(temp_data, test_size=2/3, random_state=42)

# %%
from sklearn.utils.class_weight import compute_class_weight

# tinh class weight tren tap train
classes = np.array([0, 1])
weights = compute_class_weight(class_weight="balanced", classes=classes, y=train_data["label"])
class_weight = {0: weights[0], 1: weights[1]}

# gan sample_weight cho tung dong
train_data["sample_weight"] = train_data["label"].map(class_weight)
validation_data["sample_weight"] = validation_data["label"].map(class_weight)
test_data["sample_weight"] = test_data["label"].map(class_weight)

# Convert the dataset into a TensorFlow dataset.
train_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    train_data, label="label", weight="sample_weight"
)         
val_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    validation_data, label="label", weight="sample_weight"
)
test_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    test_data, label="label", weight="sample_weight"
)
# Out:
# 2026-07-04 08:47:30.282246: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:984] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2026-07-04 08:47:30.283760: W tensorflow/core/common_runtime/gpu/gpu_device.cc:2251] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...

# %%
import keras

# %%
# %%time

# Train a Gradient Boosted Trees model.
model = tfdf.keras.GradientBoostedTreesModel()

# Add evaluation metrics
model.compile(
    metrics=["accuracy"]
)
model.fit(x=train_ds)

# # Train a Gradient Boosted Trees model.
# model = tfdf.keras.GradientBoostedTreesModel(num_trees=1500)
# model.fit(train_ds)
# Out:
# Use /tmp/tmpb3irqtyl as temporary training directory
# Reading training dataset...
# [WARNING 26-07-04 08:47:30.4266 UTC gradient_boosted_trees.cc:1840] "goss_alpha" set but "sampling_method" not equal to "GOSS".
# [WARNING 26-07-04 08:47:30.4266 UTC gradient_boosted_trees.cc:1851] "goss_beta" set but "sampling_method" not equal to "GOSS".
# [WARNING 26-07-04 08:47:30.4267 UTC gradient_boosted_trees.cc:1865] "selective_gradient_boosting_ratio" set but "sampling_method" not equal to "SELGB".
# Training dataset read in 0:00:03.106283. Found 157612 examples.
# Training model...
# Model trained in 0:00:38.334651
# Compiling model...
# [INFO 26-07-04 08:48:11.8745 UTC kernel.cc:1233] Loading model from path /tmp/tmpb3irqtyl/model/ with prefix 7631548933e541ac
# [INFO 26-07-04 08:48:11.8889 UTC quick_scorer_extended.cc:911] The binary was compiled without AVX2 support, but your CPU supports it. Enable it for faster model inference.
# [INFO 26-07-04 08:48:11.8904 UTC abstract_model.cc:1362] Engine "GradientBoostedTreesQuickScorerExtended" built
# [INFO 26-07-04 08:48:11.8904 UTC kernel.cc:1061] Use fast generic engine
# Model compiled.
# CPU times: user 4min 44s, sys: 3.29 s, total: 4min 47s
# Wall time: 44.5 s

# %%
# Evaluate the model
evaluate = model.evaluate(val_ds, return_dict=True)
print()

for name, value in evaluate.items():
    print(f"{name}: {value:.4f}")
# Out:
# WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
#  1/23 [>.............................] - ETA: 1:05 - loss: 0.0000e+00 - accuracy: 0.9140
# 13/23 [===============>..............] - ETA: 0s - loss: 0.0000e+00 - accuracy: 0.8991
# 23/23 [==============================] - 3s 4ms/step - loss: 0.0000e+00 - accuracy: 0.9007
# loss: 0.0000
# accuracy: 0.9007

# %%
# Model Summary
model.summary()
# Out:
# Model: "gradient_boosted_trees_model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
# =================================================================
# Total params: 1 (1.00 Byte)
# Trainable params: 0 (0.00 Byte)
# Non-trainable params: 1 (1.00 Byte)
# _________________________________________________________________
# Type: "GRADIENT_BOOSTED_TREES"
# Task: CLASSIFICATION
# Label: "__LABEL"
#
# Input Features (16):
# 	GrayLevelNonUniformity
# 	GrayLevelNonUniformityNormalized
# 	GrayLevelVariance
# 	HighGrayLevelRunEmphasis
# 	LongRunEmphasis
# 	LongRunHighGrayLevelEmphasis
# 	LongRunLowGrayLevelEmphasis
# 	LowGrayLevelRunEmphasis
# 	RunEntropy
# 	RunLengthNonUniformity
# 	RunLengthNonUniformityNormalized
# 	RunPercentage
# 	RunVariance
# 	ShortRunEmphasis
# 	ShortRunHighGrayLevelEmphasis
# 	ShortRunLowGrayLevelEmphasis
#
# Trained with weights
#
# Variable Importance: INV_MEAN_MIN_DEPTH:
#     1.     "LongRunHighGrayLevelEmphasis"  0.232503 ################
#     2.           "GrayLevelNonUniformity"  0.225816 ##############
#     3. "RunLengthNonUniformityNormalized"  0.208870 #########
#     4.                       "RunEntropy"  0.203648 #######
#     5.     "ShortRunLowGrayLevelEmphasis"  0.200915 ######
#     6.                      "RunVariance"  0.198862 ######
#     7.    "ShortRunHighGrayLevelEmphasis"  0.194785 #####
#     8.                "GrayLevelVariance"  0.193294 ####
#     9.         "HighGrayLevelRunEmphasis"  0.191237 ####
#    10.          "LowGrayLevelRunEmphasis"  0.191083 ####
#    11.      "LongRunLowGrayLevelEmphasis"  0.189677 ###
#    12.                 "ShortRunEmphasis"  0.189526 ###
#    13. "GrayLevelNonUniformityNormalized"  0.185581 ##
#    14.           "RunLengthNonUniformity"  0.183718 ##
#    15.                  "LongRunEmphasis"  0.182256 #
#    16.                    "RunPercentage"  0.176435
#
# Variable Importance: NUM_AS_ROOT:
#     1.           "GrayLevelNonUniformity" 49.000000 ################
#     2.     "LongRunHighGrayLevelEmphasis" 46.000000 ###############
#     3. "RunLengthNonUniformityNormalized" 33.000000 ##########
#     4.     "ShortRunLowGrayLevelEmphasis" 26.000000 ########
#     5.          "LowGrayLevelRunEmphasis" 18.000000 #####
#     6.         "HighGrayLevelRunEmphasis" 15.000000 ####
#     7.                      "RunVariance" 15.000000 ####
#     8.           "RunLengthNonUniformity" 14.000000 ####
#     9.      "LongRunLowGrayLevelEmphasis" 13.000000 ####
#    10.                       "RunEntropy" 13.000000 ####
#    11.                 "ShortRunEmphasis" 12.000000 ###
#    12.    "ShortRunHighGrayLevelEmphasis"  7.000000 ##
#    13. "GrayLevelNonUniformityNormalized"  4.000000 #
#    14.                "GrayLevelVariance"  3.000000
#    15.                  "LongRunEmphasis"  2.000000
#    16.                    "RunPercentage"  1.000000
#
# Variable Importance: NUM_NODES:
#     1.     "LongRunHighGrayLevelEmphasis" 901.000000 ################
#     2.                       "RunEntropy" 703.000000 ###########
#     3.           "GrayLevelNonUniformity" 664.000000 ##########
#     4.                "GrayLevelVariance" 568.000000 ########
#     5.     "ShortRunLowGrayLevelEmphasis" 524.000000 #######
#     6.    "ShortRunHighGrayLevelEmphasis" 512.000000 ######
#     7.      "LongRunLowGrayLevelEmphasis" 453.000000 #####
#     8.                      "RunVariance" 436.000000 #####
#     9.         "HighGrayLevelRunEmphasis" 420.000000 ####
#    10. "GrayLevelNonUniformityNormalized" 401.000000 ####
#    11.                 "ShortRunEmphasis" 372.000000 ###
#    12. "RunLengthNonUniformityNormalized" 350.000000 ###
#    13.          "LowGrayLevelRunEmphasis" 318.000000 ##
#    14.                  "LongRunEmphasis" 252.000000
#    15.           "RunLengthNonUniformity" 222.000000
#    16.                    "RunPercentage" 213.000000
#
# Variable Importance: SUM_SCORE:
#     1.     "ShortRunLowGrayLevelEmphasis" 35175.550804 ################
#     2.     "LongRunHighGrayLevelEmphasis" 23645.291574 ##########
#     3.    "ShortRunHighGrayLevelEmphasis" 16454.148699 #######
#     4.                       "RunEntropy" 15779.040679 ######
#     5.          "LowGrayLevelRunEmphasis" 8748.328344 ###
#     6.                      "RunVariance" 8708.180811 ###
#     7.           "GrayLevelNonUniformity" 7796.683209 ###
#     8.         "HighGrayLevelRunEmphasis" 6544.355654 ##
#     9.                "GrayLevelVariance" 4080.919826 #
#    10.      "LongRunLowGrayLevelEmphasis" 3342.616702 #
#    11. "RunLengthNonUniformityNormalized" 2355.342131
#    12.                 "ShortRunEmphasis" 2342.892845
#    13. "GrayLevelNonUniformityNormalized" 1561.715441
#    14.           "RunLengthNonUniformity" 1123.262614
#    15.                    "RunPercentage" 1059.157998
#    16.                  "LongRunEmphasis" 893.226385
#
#
#
# Loss: BINOMIAL_LOG_LIKELIHOOD
# Validation loss value: 0.579747
# Number of trees per iteration: 1
# Node format: NOT_SET
# Number of trees: 271
# Total number of nodes: 14889
#
# Number of nodes by tree:
# Count: 271 Average: 54.941 StdDev: 7.11297
# Min: 35 Max: 63 Ignored: 0
# ----------------------------------------------
# [ 35, 36)  3   1.11%   1.11% #
# [ 36, 37)  0   0.00%   1.11%
# [ 37, 39)  0   0.00%   1.11%
# [ 39, 40)  2   0.74%   1.85%
# [ 40, 42)  5   1.85%   3.69% #
# [ 42, 43)  0   0.00%   3.69%
# [ 43, 45) 15   5.54%   9.23% ###
# [ 45, 46) 17   6.27%  15.50% ###
# [ 46, 48) 16   5.90%  21.40% ###
# [ 48, 49)  0   0.00%  21.40%
# [ 49, 50) 16   5.90%  27.31% ###
# [ 50, 52) 15   5.54%  32.84% ###
# [ 52, 53)  0   0.00%  32.84%
# [ 53, 55) 13   4.80%  37.64% ##
# [ 55, 56) 24   8.86%  46.49% ####
# [ 56, 58) 30  11.07%  57.56% #####
# [ 58, 59)  0   0.00%  57.56%
# [ 59, 61) 28  10.33%  67.90% #####
# [ 61, 62) 31  11.44%  79.34% ######
# [ 62, 63] 56  20.66% 100.00% ##########
#
# Depth by leafs:
# Count: 7580 Average: 4.89842 StdDev: 0.405077
# Min: 2 Max: 5 Ignored: 0
# ----------------------------------------------
# [ 2, 3)   46   0.61%   0.61%
# [ 3, 4)  138   1.82%   2.43%
# [ 4, 5)  356   4.70%   7.12% #
# [ 5, 5] 7040  92.88% 100.00% ##########
#
# Number of training obs by leaf:
# Count: 7580 Average: 5072.85 StdDev: 17296.1
# Min: 5 Max: 138523 Ignored: 0
# ----------------------------------------------
# [      5,   6930) 6638  87.57%  87.57% ##########
# [   6930,  13856)  391   5.16%  92.73% #
# [  13856,  20782)  125   1.65%  94.38%
# [  20782,  27708)   63   0.83%  95.21%
# [  27708,  34634)   52   0.69%  95.90%
# [  34634,  41560)   34   0.45%  96.35%
# [  41560,  48486)   32   0.42%  96.77%
# [  48486,  55412)   28   0.37%  97.14%
# [  55412,  62338)   25   0.33%  97.47%
# [  62338,  69264)   18   0.24%  97.70%
# [  69264,  76190)   12   0.16%  97.86%
# [  76190,  83116)   22   0.29%  98.15%
# [  83116,  90042)   19   0.25%  98.40%
# [  90042,  96968)   20   0.26%  98.67%
# [  96968, 103894)   22   0.29%  98.96%
# [ 103894, 110820)    9   0.12%  99.08%
# [ 110820, 117746)   15   0.20%  99.27%
# [ 117746, 124672)   23   0.30%  99.58%
# [ 124672, 131598)   15   0.20%  99.78%
# [ 131598, 138523]   17   0.22% 100.00%
#
# Attribute in nodes:
# 	901 : LongRunHighGrayLevelEmphasis [NUMERICAL]
# 	703 : RunEntropy [NUMERICAL]
# 	664 : GrayLevelNonUniformity [NUMERICAL]
# 	568 : GrayLevelVariance [NUMERICAL]
# 	524 : ShortRunLowGrayLevelEmphasis [NUMERICAL]
# 	512 : ShortRunHighGrayLevelEmphasis [NUMERICAL]
# 	453 : LongRunLowGrayLevelEmphasis [NUMERICAL]
# 	436 : RunVariance [NUMERICAL]
# 	420 : HighGrayLevelRunEmphasis [NUMERICAL]
# 	401 : GrayLevelNonUniformityNormalized [NUMERICAL]
# 	372 : ShortRunEmphasis [NUMERICAL]
# 	350 : RunLengthNonUniformityNormalized [NUMERICAL]
# 	318 : LowGrayLevelRunEmphasis [NUMERICAL]
# 	252 : LongRunEmphasis [NUMERICAL]
# 	222 : RunLengthNonUniformity [NUMERICAL]
# 	213 : RunPercentage [NUMERICAL]
#
# Attribute in nodes with depth <= 0:
# 	49 : GrayLevelNonUniformity [NUMERICAL]
# 	46 : LongRunHighGrayLevelEmphasis [NUMERICAL]
# 	33 : RunLengthNonUniformityNormalized [NUMERICAL]
# 	26 : ShortRunLowGrayLevelEmphasis [NUMERICAL]
# 	18 : LowGrayLevelRunEmphasis [NUMERICAL]
# 	15 : RunVariance [NUMERICAL]
# 	15 : HighGrayLevelRunEmphasis [NUMERICAL]
# 	14 : RunLengthNonUniformity [NUMERICAL]
# 	13 : RunEntropy [NUMERICAL]
# 	13 : LongRunLowGrayLevelEmphasis [NUMERICAL]
# 	12 : ShortRunEmphasis [NUMERICAL]
# 	7 : ShortRunHighGrayLevelEmphasis [NUMERICAL]
# 	4 : GrayLevelNonUniformityNormalized [NUMERICAL]
# 	3 : GrayLevelVariance [NUMERICAL]
# 	2 : LongRunEmphasis [NUMERICAL]
# 	1 : RunPercentage [NUMERICAL]
#
# Attribute in nodes with depth <= 1:
# 	96 : LongRunHighGrayLevelEmphasis [NUMERICAL]
# 	96 : GrayLevelNonUniformity [NUMERICAL]
# 	82 : RunLengthNonUniformityNormalized [NUMERICAL]
# 	67 : RunVariance [NUMERICAL]
# 	63 : RunEntropy [NUMERICAL]
# 	58 : ShortRunHighGrayLevelEmphasis [NUMERICAL]
# 	50 : ShortRunLowGrayLevelEmphasis [NUMERICAL]
# 	50 : HighGrayLevelRunEmphasis [NUMERICAL]
# 	49 : GrayLevelVariance [NUMERICAL]
# 	39 : ShortRunEmphasis [NUMERICAL]
# 	38 : LowGrayLevelRunEmphasis [NUMERICAL]
# 	33 : LongRunLowGrayLevelEmphasis [NUMERICAL]
# 	32 : LongRunEmphasis [NUMERICAL]
# 	30 : RunLengthNonUniformity [NUMERICAL]
# 	22 : GrayLevelNonUniformityNormalized [NUMERICAL]
# 	8 : RunPercentage [NUMERICAL]
#
# Attribute in nodes with depth <= 2:
# 	235 : LongRunHighGrayLevelEmphasis [NUMERICAL]
# 	197 : GrayLevelNonUniformity [NUMERICAL]
# 	152 : RunEntropy [NUMERICAL]
# 	142 : RunVariance [NUMERICAL]
# 	132 : RunLengthNonUniformityNormalized [NUMERICAL]
# 	128 : ShortRunHighGrayLevelEmphasis [NUMERICAL]
# 	125 : GrayLevelVariance [NUMERICAL]
# 	108 : HighGrayLevelRunEmphasis [NUMERICAL]
# 	101 : ShortRunLowGrayLevelEmphasis [NUMERICAL]
# 	99 : LongRunLowGrayLevelEmphasis [NUMERICAL]
# 	94 : ShortRunEmphasis [NUMERICAL]
# 	91 : GrayLevelNonUniformityNormalized [NUMERICAL]
# 	87 : LowGrayLevelRunEmphasis [NUMERICAL]
# 	69 : LongRunEmphasis [NUMERICAL]
# 	57 : RunLengthNonUniformity [NUMERICAL]
# 	34 : RunPercentage [NUMERICAL]
#
# Attribute in nodes with depth <= 3:
# 	468 : LongRunHighGrayLevelEmphasis [NUMERICAL]
# 	365 : RunEntropy [NUMERICAL]
# 	356 : GrayLevelNonUniformity [NUMERICAL]
# 	274 : GrayLevelVariance [NUMERICAL]
# 	255 : ShortRunHighGrayLevelEmphasis [NUMERICAL]
# 	253 : RunVariance [NUMERICAL]
# 	250 : ShortRunLowGrayLevelEmphasis [NUMERICAL]
# 	219 : LongRunLowGrayLevelEmphasis [NUMERICAL]
# 	210 : RunLengthNonUniformityNormalized [NUMERICAL]
# 	208 : HighGrayLevelRunEmphasis [NUMERICAL]
# 	206 : GrayLevelNonUniformityNormalized [NUMERICAL]
# 	202 : ShortRunEmphasis [NUMERICAL]
# 	160 : LowGrayLevelRunEmphasis [NUMERICAL]
# 	133 : LongRunEmphasis [NUMERICAL]
# 	127 : RunLengthNonUniformity [NUMERICAL]
# 	103 : RunPercentage [NUMERICAL]
#
# Attribute in nodes with depth <= 5:
# 	901 : LongRunHighGrayLevelEmphasis [NUMERICAL]
# 	703 : RunEntropy [NUMERICAL]
# 	664 : GrayLevelNonUniformity [NUMERICAL]
# 	568 : GrayLevelVariance [NUMERICAL]
# 	524 : ShortRunLowGrayLevelEmphasis [NUMERICAL]
# 	512 : ShortRunHighGrayLevelEmphasis [NUMERICAL]
# 	453 : LongRunLowGrayLevelEmphasis [NUMERICAL]
# 	436 : RunVariance [NUMERICAL]
# 	420 : HighGrayLevelRunEmphasis [NUMERICAL]
# 	401 : GrayLevelNonUniformityNormalized [NUMERICAL]
# 	372 : ShortRunEmphasis [NUMERICAL]
# 	350 : RunLengthNonUniformityNormalized [NUMERICAL]
# 	318 : LowGrayLevelRunEmphasis [NUMERICAL]
# 	252 : LongRunEmphasis [NUMERICAL]
# 	222 : RunLengthNonUniformity [NUMERICAL]
# 	213 : RunPercentage [NUMERICAL]
#
# Condition type in nodes:
# 	7309 : HigherCondition
# Condition type in nodes with depth <= 0:
# 	271 : HigherCondition
# Condition type in nodes with depth <= 1:
# 	813 : HigherCondition
# Condition type in nodes with depth <= 2:
# 	1851 : HigherCondition
# Condition type in nodes with depth <= 3:
# 	3789 : HigherCondition
# Condition type in nodes with depth <= 5:
# 	7309 : HigherCondition
#
# Training logs:
# Number of iteration to final model: 271
# 	Iter:1 train-loss:1.288499 valid-loss:1.290166  train-accuracy:0.821737 valid-accuracy:0.819846
# 	Iter:2 train-loss:1.208099 valid-loss:1.210781  train-accuracy:0.823490 valid-accuracy:0.817668
# 	Iter:3 train-loss:1.140262 valid-loss:1.144058  train-accuracy:0.835366 valid-accuracy:0.829341
# 	Iter:4 train-loss:1.082019 valid-loss:1.086357  train-accuracy:0.837765 valid-accuracy:0.832998
# 	Iter:5 train-loss:1.032342 valid-loss:1.038443  train-accuracy:0.838522 valid-accuracy:0.834113
# 	Iter:6 train-loss:0.991342 valid-loss:0.999402  train-accuracy:0.840867 valid-accuracy:0.836990
# 	Iter:16 train-loss:0.761977 valid-loss:0.778912  train-accuracy:0.856972 valid-accuracy:0.853383
# 	Iter:26 train-loss:0.672791 valid-loss:0.699828  train-accuracy:0.865028 valid-accuracy:0.859498
# 	Iter:36 train-loss:0.629474 valid-loss:0.662595  train-accuracy:0.872218 valid-accuracy:0.864698
# 	Iter:46 train-loss:0.599528 valid-loss:0.640060  train-accuracy:0.877234 valid-accuracy:0.865990
# 	Iter:56 train-loss:0.578533 valid-loss:0.626873  train-accuracy:0.882118 valid-accuracy:0.868384
# 	Iter:66 train-loss:0.561904 valid-loss:0.617490  train-accuracy:0.884471 valid-accuracy:0.867405
# 	Iter:76 train-loss:0.549605 valid-loss:0.611534  train-accuracy:0.887328 valid-accuracy:0.870079
# 	Iter:86 train-loss:0.537872 valid-loss:0.605988  train-accuracy:0.889652 valid-accuracy:0.872244
# 	Iter:96 train-loss:0.528477 valid-loss:0.601258  train-accuracy:0.891838 valid-accuracy:0.872753
# 	Iter:106 train-loss:0.518916 valid-loss:0.598107  train-accuracy:0.894010 valid-accuracy:0.872744
# 	Iter:116 train-loss:0.509133 valid-loss:0.594643  train-accuracy:0.895896 valid-accuracy:0.874617
# 	Iter:126 train-loss:0.502046 valid-loss:0.592680  train-accuracy:0.897516 valid-accuracy:0.874583
# 	Iter:136 train-loss:0.494952 valid-loss:0.590714  train-accuracy:0.899648 valid-accuracy:0.875634
# 	Iter:146 train-loss:0.487677 valid-loss:0.589067  train-accuracy:0.900920 valid-accuracy:0.876448
# 	Iter:156 train-loss:0.480486 valid-loss:0.587157  train-accuracy:0.902494 valid-accuracy:0.877058
# 	Iter:166 train-loss:0.475310 valid-loss:0.585869  train-accuracy:0.904010 valid-accuracy:0.877498
# 	Iter:176 train-loss:0.468694 valid-loss:0.584440  train-accuracy:0.906086 valid-accuracy:0.878041
# 	Iter:186 train-loss:0.463680 valid-loss:0.584339  train-accuracy:0.907713 valid-accuracy:0.878020
# 	Iter:196 train-loss:0.458509 valid-loss:0.584076  train-accuracy:0.909038 valid-accuracy:0.878664
# 	Iter:206 train-loss:0.453299 valid-loss:0.583214  train-accuracy:0.910589 valid-accuracy:0.879342
# 	Iter:216 train-loss:0.448969 valid-loss:0.582647  train-accuracy:0.912283 valid-accuracy:0.879748
# 	Iter:226 train-loss:0.444301 valid-loss:0.581798  train-accuracy:0.913387 valid-accuracy:0.879333
# 	Iter:236 train-loss:0.440600 valid-loss:0.581771  train-accuracy:0.914100 valid-accuracy:0.879875
# 	Iter:246 train-loss:0.436151 valid-loss:0.581475  train-accuracy:0.914985 valid-accuracy:0.879888
# 	Iter:256 train-loss:0.432468 valid-loss:0.580838  train-accuracy:0.916427 valid-accuracy:0.879494
# 	Iter:266 train-loss:0.428417 valid-loss:0.580276  train-accuracy:0.917149 valid-accuracy:0.879337
# 	Iter:276 train-loss:0.424556 valid-loss:0.580083  train-accuracy:0.918323 valid-accuracy:0.878379
# 	Iter:286 train-loss:0.420355 valid-loss:0.580185  train-accuracy:0.920089 valid-accuracy:0.876938
# 	Iter:296 train-loss:0.416455 valid-loss:0.580609  train-accuracy:0.921303 valid-accuracy:0.877107

# %%
# Model features
model.make_inspector().features()
# Out:
# ["GrayLevelNonUniformity" (1; #0),
#  "GrayLevelNonUniformityNormalized" (1; #1),
#  "GrayLevelVariance" (1; #2),
#  "HighGrayLevelRunEmphasis" (1; #3),
#  "LongRunEmphasis" (1; #4),
#  "LongRunHighGrayLevelEmphasis" (1; #5),
#  "LongRunLowGrayLevelEmphasis" (1; #6),
#  "LowGrayLevelRunEmphasis" (1; #7),
#  "RunEntropy" (1; #8),
#  "RunLengthNonUniformity" (1; #9),
#  "RunLengthNonUniformityNormalized" (1; #10),
#  "RunPercentage" (1; #11),
#  "RunVariance" (1; #12),
#  "ShortRunEmphasis" (1; #13),
#  "ShortRunHighGrayLevelEmphasis" (1; #14),
#  "ShortRunLowGrayLevelEmphasis" (1; #15)]

# %%
# Feature importance
model.make_inspector().variable_importances()
# Out:
# {'INV_MEAN_MIN_DEPTH': [("LongRunHighGrayLevelEmphasis" (1; #5),
#    0.23250270674538515),
#   ("GrayLevelNonUniformity" (1; #0), 0.22581551192932114),
#   ("RunLengthNonUniformityNormalized" (1; #10), 0.2088695274439359),
#   ("RunEntropy" (1; #8), 0.2036478691614809),
#   ("ShortRunLowGrayLevelEmphasis" (1; #15), 0.20091477595602775),
#   ("RunVariance" (1; #12), 0.19886186762534547),
#   ("ShortRunHighGrayLevelEmphasis" (1; #14), 0.19478482853651574),
#   ("GrayLevelVariance" (1; #2), 0.19329406754440537),
#   ("HighGrayLevelRunEmphasis" (1; #3), 0.19123749477885796),
#   ("LowGrayLevelRunEmphasis" (1; #7), 0.19108319477272964),
#   ("LongRunLowGrayLevelEmphasis" (1; #6), 0.1896774061248326),
#   ("ShortRunEmphasis" (1; #13), 0.1895256861956172),
#   ("GrayLevelNonUniformityNormalized" (1; #1), 0.1855810771550933),
#   ("RunLengthNonUniformity" (1; #9), 0.18371809773503217),
#   ("LongRunEmphasis" (1; #4), 0.18225612990556775),
#   ("RunPercentage" (1; #11), 0.17643485545447057)],
#  'SUM_SCORE': [("ShortRunLowGrayLevelEmphasis" (1; #15), 35175.55080438257),
#   ("LongRunHighGrayLevelEmphasis" (1; #5), 23645.291573919712),
#   ("ShortRunHighGrayLevelEmphasis" (1; #14), 16454.14869941013),
#   ("RunEntropy" (1; #8), 15779.040678949448),
#   ("LowGrayLevelRunEmphasis" (1; #7), 8748.328343700206),
#   ("RunVariance" (1; #12), 8708.180811451788),
#   ("GrayLevelNonUniformity" (1; #0), 7796.683209050507),
#   ("HighGrayLevelRunEmphasis" (1; #3), 6544.355654492473),
#   ("GrayLevelVariance" (1; #2), 4080.919825965248),
#   ("LongRunLowGrayLevelEmphasis" (1; #6), 3342.6167018760684),
#   ("RunLengthNonUniformityNormalized" (1; #10), 2355.3421311741836),
#   ("ShortRunEmphasis" (1; #13), 2342.8928447329226),
#   ("GrayLevelNonUniformityNormalized" (1; #1), 1561.715441459696),
#   ("RunLengthNonUniformity" (1; #9), 1123.262613895607),
#   ("RunPercentage" (1; #11), 1059.1579978397908),
#   ("LongRunEmphasis" (1; #4), 893.2263851911765)],
#  'NUM_AS_ROOT': [("GrayLevelNonUniformity" (1; #0), 49.0),
#   ("LongRunHighGrayLevelEmphasis" (1; #5), 46.0),
#   ("RunLengthNonUniformityNormalized" (1; #10), 33.0),
#   ("ShortRunLowGrayLevelEmphasis" (1; #15), 26.0),
#   ("LowGrayLevelRunEmphasis" (1; #7), 18.0),
#   ("HighGrayLevelRunEmphasis" (1; #3), 15.0),
#   ("RunVariance" (1; #12), 15.0),
#   ("RunLengthNonUniformity" (1; #9), 14.0),
#   ("LongRunLowGrayLevelEmphasis" (1; #6), 13.0),
#   ("RunEntropy" (1; #8), 13.0),
#   ("ShortRunEmphasis" (1; #13), 12.0),
#   ("ShortRunHighGrayLevelEmphasis" (1; #14), 7.0),
#   ("GrayLevelNonUniformityNormalized" (1; #1), 4.0),
#   ("GrayLevelVariance" (1; #2), 3.0),
#   ("LongRunEmphasis" (1; #4), 2.0),
#   ("RunPercentage" (1; #11), 1.0)],
#  'NUM_NODES': [("LongRunHighGrayLevelEmphasis" (1; #5), 901.0),
#   ("RunEntropy" (1; #8), 703.0),
#   ("GrayLevelNonUniformity" (1; #0), 664.0),
#   ("GrayLevelVariance" (1; #2), 568.0),
#   ("ShortRunLowGrayLevelEmphasis" (1; #15), 524.0),
#   ("ShortRunHighGrayLevelEmphasis" (1; #14), 512.0),
#   ("LongRunLowGrayLevelEmphasis" (1; #6), 453.0),
#   ("RunVariance" (1; #12), 436.0),
#   ("HighGrayLevelRunEmphasis" (1; #3), 420.0),
#   ("GrayLevelNonUniformityNormalized" (1; #1), 401.0),
#   ("ShortRunEmphasis" (1; #13), 372.0),
#   ("RunLengthNonUniformityNormalized" (1; #10), 350.0),
#   ("LowGrayLevelRunEmphasis" (1; #7), 318.0),
#   ("LongRunEmphasis" (1; #4), 252.0),
#   ("RunLengthNonUniformity" (1; #9), 222.0),
#   ("RunPercentage" (1; #11), 213.0)]}

# %%
# Model self evaluation
model.make_inspector().evaluation()
# Out:
# Evaluation(num_examples=None, accuracy=0.8794384598731995, loss=0.5797470211982727, rmse=None, ndcg=None, aucs=None, auuc=None, qini=None)

# %%
logs = model.make_inspector().training_logs()

plt.figure(figsize=(12, 4))
plt.subplot(1, 2, 1)
plt.plot([log.num_trees for log in logs], [log.evaluation.accuracy for log in logs])
plt.xlabel("Number of trees")
plt.ylabel("Accuracy (out-of-bag)")
plt.subplot(1, 2, 2)
plt.plot([log.num_trees for log in logs], [log.evaluation.loss for log in logs])
plt.xlabel("Number of trees")
plt.ylabel("Logloss (out-of-bag)")
plt.show()

# %% [markdown]
# Calculate the score of our hold-out validation dataset

# %%
predictions = model.predict(val_ds)
y_true      = validation_data["label"]

from sklearn.metrics import roc_auc_score
ROC_AUC = roc_auc_score(y_true, predictions)
print("The ROC AUC score is %.5f" % ROC_AUC )
# Out:
#  1/23 [>.............................] - ETA: 1s
# 13/23 [===============>..............] - ETA: 0s
# 23/23 [==============================] - 0s 4ms/step
# The ROC AUC score is 0.94987

# %%
# Compute binary classification metrics with sklearn
import numpy as np
from sklearn.metrics import (
    accuracy_score,
    precision_score,
    recall_score,
    f1_score,
    roc_auc_score,
    average_precision_score,
    confusion_matrix,
    classification_report,
    matthews_corrcoef,
    log_loss,
    brier_score_loss,
)

# Get predictions (probabilities or class labels)
preds = model.predict(test_ds)
# If model outputs probabilities, convert to labels by threshold 0.5
if preds.ndim == 2:
    # For TFDF classification, preds may be class probabilities with shape (N, 2)
    if preds.shape[1] == 2:
        pos_probs = preds[:, 1]
    else:
        # If single-probability column (positive class)
        pos_probs = preds[:, -1]
    y_pred = (pos_probs >= 0.5).astype(int)
else:
    # Already class labels
    y_pred = preds.astype(int)
    pos_probs = None

# Ground truth labels (must be 0/1 integers)
y_true = test_data["label"].astype(int).to_numpy()

# Core metrics
metrics = {}
metrics["accuracy"] = accuracy_score(y_true, y_pred)
metrics["precision"] = precision_score(y_true, y_pred, zero_division=0)
metrics["recall"] = recall_score(y_true, y_pred, zero_division=0)
metrics["f1"] = f1_score(y_true, y_pred, zero_division=0)
metrics["mcc"] = matthews_corrcoef(y_true, y_pred)

# Probabilistic metrics (only if we have probabilities)
if pos_probs is not None:
    metrics["roc_auc"] = roc_auc_score(y_true, pos_probs)
    metrics["pr_auc"] = average_precision_score(y_true, pos_probs)
    metrics["log_loss"] = log_loss(y_true, pos_probs, labels=[0,1])
    metrics["brier_score"] = brier_score_loss(y_true, pos_probs)

# Confusion matrix and detailed report
cm = confusion_matrix(y_true, y_pred, labels=[0,1])
report = classification_report(y_true, y_pred, digits=4)

print("Sklearn binary metrics:")
for k, v in metrics.items():
    print(f"{k}: {v:.4f}")
print("\nConfusion matrix:\n", cm)
print("\nClassification report:\n", report)
# Out:
#  1/46 [..............................] - ETA: 2s
# 13/46 [=======>......................] - ETA: 0s
# 26/46 [===============>..............] - ETA: 0s
# 35/46 [=====================>........] - ETA: 0s
# 46/46 [==============================] - 0s 4ms/step
# Sklearn binary metrics:
# accuracy: 0.8964
# precision: 0.3731
# recall: 0.8435
# f1: 0.5174
# mcc: 0.5181
# roc_auc: 0.9488
# pr_auc: 0.6960
# log_loss: 0.2500
# brier_score: 0.0756
#
# Confusion matrix:
#  [[37868  4200]
#  [  464  2500]]
#
# Classification report:
#                precision    recall  f1-score   support
#
#            0     0.9879    0.9002    0.9420     42068
#            1     0.3731    0.8435    0.5174      2964
#
#     accuracy                         0.8964     45032
#    macro avg     0.6805    0.8718    0.7297     45032
# weighted avg     0.9474    0.8964    0.9140     45032
