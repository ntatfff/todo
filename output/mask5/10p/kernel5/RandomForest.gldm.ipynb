# %%
# Import packages and modules
import numpy  as np
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow_decision_forests as tfdf

from sklearn.model_selection import train_test_split
# Out:
# 2026-09-12 10:46:29.002222: I tensorflow/core/util/port.cc:113] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2026-09-12 10:46:29.359289: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2026-09-12 10:46:34.006376: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
# Check the version of TensorFlow Decision Forests
print("Found TensorFlow Decision Forests v" + tfdf.__version__)
# Out:
# Found TensorFlow Decision Forests v1.9.1

# %%
datasetPath = "dataset/10p/all/kernel3/"

# %%
# Parameters
datasetPath = "dataset/mask5/10p/gldm/kernel5/"

# %%
# train/validation/test = 70/10/20
train_data = pd.read_csv(f"{datasetPath}dataset.train.csv")
validation_data = pd.read_csv(f"{datasetPath}dataset.validation.csv")
test_data = pd.read_csv(f"{datasetPath}dataset.test.csv")

# %%
from sklearn.utils.class_weight import compute_class_weight

# tinh class weight tren tap train
classes = np.array([0, 1])
weights = compute_class_weight(class_weight="balanced", classes=classes, y=train_data["label"])
class_weight = {0: weights[0], 1: weights[1]}

# gan sample_weight cho tung dong
train_data["sample_weight"] = train_data["label"].map(class_weight)
validation_data["sample_weight"] = validation_data["label"].map(class_weight)
test_data["sample_weight"] = test_data["label"].map(class_weight)

# Convert the dataset into a TensorFlow dataset.
train_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    train_data, label="label", weight="sample_weight"
)         
val_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    validation_data, label="label", weight="sample_weight"
)
test_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    test_data, label="label", weight="sample_weight"
)
# Out:
# 2026-09-12 10:46:46.913775: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:984] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2026-09-12 10:46:46.915393: W tensorflow/core/common_runtime/gpu/gpu_device.cc:2251] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...

# %%
import keras

# %%
# %%time

# Train a Random Forest model.
model = tfdf.keras.RandomForestModel()

# Add evaluation metrics
model.compile(
    metrics=["accuracy"]
)
model.fit(x=train_ds)

# # Train a Gradient Boosted Trees model.
# model = tfdf.keras.GradientBoostedTreesModel(num_trees=1500)
# model.fit(train_ds)
# Out:
# Use /tmp/tmpfv4i8w70 as temporary training directory
# Reading training dataset...
# Training dataset read in 0:00:03.460885. Found 7617 examples.
# Training model...
# Model trained in 0:00:00.483395
# Compiling model...
# [INFO 26-09-12 10:46:50.9304 UTC kernel.cc:1233] Loading model from path /tmp/tmpfv4i8w70/model/ with prefix 371da82bde25483a
# [INFO 26-09-12 10:46:51.0255 UTC decision_forest.cc:734] Model loaded with 300 root(s), 70092 node(s), and 14 input feature(s).
# [INFO 26-09-12 10:46:51.0255 UTC abstract_model.cc:1362] Engine "RandomForestOptPred" built
# [INFO 26-09-12 10:46:51.0255 UTC kernel.cc:1061] Use fast generic engine
# Model compiled.
# CPU times: user 9.11 s, sys: 118 ms, total: 9.23 s
# Wall time: 7.09 s

# %%
# Evaluate the model
evaluate = model.evaluate(val_ds, return_dict=True)
print()

for name, value in evaluate.items():
    print(f"{name}: {value:.4f}")
# Out:
# WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 1/2 [==============>...............] - ETA: 3s - loss: 0.0000e+00 - accuracy: 0.9890
# 2/2 [==============================] - 3s 8ms/step - loss: 0.0000e+00 - accuracy: 0.9888
# loss: 0.0000
# accuracy: 0.9888

# %%
# Model Summary
model.summary()
# Out:
# Model: "random_forest_model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
# =================================================================
# Total params: 1 (1.00 Byte)
# Trainable params: 0 (0.00 Byte)
# Non-trainable params: 1 (1.00 Byte)
# _________________________________________________________________
# Type: "RANDOM_FOREST"
# Task: CLASSIFICATION
# Label: "__LABEL"
#
# Input Features (14):
# 	DependenceEntropy
# 	DependenceNonUniformity
# 	DependenceNonUniformityNormalized
# 	DependenceVariance
# 	GrayLevelNonUniformity
# 	GrayLevelVariance
# 	HighGrayLevelEmphasis
# 	LargeDependenceEmphasis
# 	LargeDependenceHighGrayLevelEmphasis
# 	LargeDependenceLowGrayLevelEmphasis
# 	LowGrayLevelEmphasis
# 	SmallDependenceEmphasis
# 	SmallDependenceHighGrayLevelEmphasis
# 	SmallDependenceLowGrayLevelEmphasis
#
# Trained with weights
#
# Variable Importance: INV_MEAN_MIN_DEPTH:
#     1. "LargeDependenceHighGrayLevelEmphasis"  0.251016 ################
#     2.                "HighGrayLevelEmphasis"  0.244020 ###############
#     3.                    "DependenceEntropy"  0.184166 ########
#     4. "SmallDependenceHighGrayLevelEmphasis"  0.163383 #####
#     5.                 "LowGrayLevelEmphasis"  0.158392 #####
#     6.               "GrayLevelNonUniformity"  0.135100 ##
#     7.  "SmallDependenceLowGrayLevelEmphasis"  0.130924 #
#     8.  "LargeDependenceLowGrayLevelEmphasis"  0.130798 #
#     9.                    "GrayLevelVariance"  0.121740
#    10.    "DependenceNonUniformityNormalized"  0.119347
#    11.              "SmallDependenceEmphasis"  0.119323
#    12.              "DependenceNonUniformity"  0.119015
#    13.                   "DependenceVariance"  0.116243
#    14.              "LargeDependenceEmphasis"  0.114676
#
# Variable Importance: NUM_AS_ROOT:
#     1.                "HighGrayLevelEmphasis" 108.000000 ################
#     2. "LargeDependenceHighGrayLevelEmphasis" 60.000000 ########
#     3.                 "LowGrayLevelEmphasis" 54.000000 #######
#     4. "SmallDependenceHighGrayLevelEmphasis" 48.000000 ######
#     5.  "LargeDependenceLowGrayLevelEmphasis" 15.000000 #
#     6.  "SmallDependenceLowGrayLevelEmphasis"  8.000000
#     7.               "GrayLevelNonUniformity"  4.000000
#     8.                    "DependenceEntropy"  3.000000
#
# Variable Importance: NUM_NODES:
#     1. "LargeDependenceHighGrayLevelEmphasis" 3663.000000 ################
#     2.                    "DependenceEntropy" 3620.000000 ###############
#     3.                "HighGrayLevelEmphasis" 3270.000000 ############
#     4.               "GrayLevelNonUniformity" 2817.000000 #########
#     5. "SmallDependenceHighGrayLevelEmphasis" 2745.000000 ########
#     6.                    "GrayLevelVariance" 2557.000000 #######
#     7.  "SmallDependenceLowGrayLevelEmphasis" 2490.000000 ######
#     8.                 "LowGrayLevelEmphasis" 2394.000000 #####
#     9.  "LargeDependenceLowGrayLevelEmphasis" 2327.000000 #####
#    10.              "SmallDependenceEmphasis" 2083.000000 ###
#    11.                   "DependenceVariance" 1900.000000 ##
#    12.              "DependenceNonUniformity" 1698.000000
#    13.    "DependenceNonUniformityNormalized" 1686.000000
#    14.              "LargeDependenceEmphasis" 1646.000000
#
# Variable Importance: SUM_SCORE:
#     1.                "HighGrayLevelEmphasis" 353710.462261 ################
#     2. "LargeDependenceHighGrayLevelEmphasis" 290368.521159 ############
#     3. "SmallDependenceHighGrayLevelEmphasis" 168075.844787 ######
#     4.                 "LowGrayLevelEmphasis" 146412.829621 #####
#     5.                    "DependenceEntropy" 142913.225273 #####
#     6.  "LargeDependenceLowGrayLevelEmphasis" 72910.527245 ##
#     7.               "GrayLevelNonUniformity" 70797.429580 ##
#     8.  "SmallDependenceLowGrayLevelEmphasis" 60074.628296 #
#     9.                    "GrayLevelVariance" 43372.742572
#    10.              "SmallDependenceEmphasis" 35894.474435
#    11.    "DependenceNonUniformityNormalized" 35536.740614
#    12.              "DependenceNonUniformity" 34034.785819
#    13.                   "DependenceVariance" 30345.621162
#    14.              "LargeDependenceEmphasis" 26001.988390
#
#
#
# Winner takes all: true
# Out-of-bag evaluation: accuracy:0.866314 logloss:0.412653
# Number of trees: 300
# Total number of nodes: 70092
#
# Number of nodes by tree:
# Count: 300 Average: 233.64 StdDev: 13.9118
# Min: 195 Max: 279 Ignored: 0
# ----------------------------------------------
# [ 195, 199)  1   0.33%   0.33%
# [ 199, 203)  2   0.67%   1.00%
# [ 203, 207)  2   0.67%   1.67%
# [ 207, 212) 10   3.33%   5.00% ##
# [ 212, 216) 16   5.33%  10.33% ####
# [ 216, 220) 16   5.33%  15.67% ####
# [ 220, 224) 31  10.33%  26.00% ########
# [ 224, 229) 27   9.00%  35.00% #######
# [ 229, 233) 36  12.00%  47.00% #########
# [ 233, 237) 31  10.33%  57.33% ########
# [ 237, 241) 31  10.33%  67.67% ########
# [ 241, 246) 41  13.67%  81.33% ##########
# [ 246, 250) 23   7.67%  89.00% ######
# [ 250, 254) 15   5.00%  94.00% ####
# [ 254, 258)  4   1.33%  95.33% #
# [ 258, 263)  6   2.00%  97.33% #
# [ 263, 267)  5   1.67%  99.00% #
# [ 267, 271)  1   0.33%  99.33%
# [ 271, 275)  0   0.00%  99.33%
# [ 275, 279]  2   0.67% 100.00%
#
# Depth by leafs:
# Count: 35196 Average: 8.70971 StdDev: 2.52532
# Min: 2 Max: 15 Ignored: 0
# ----------------------------------------------
# [  2,  3)   12   0.03%   0.03%
# [  3,  4)  289   0.82%   0.86% #
# [  4,  5)  979   2.78%   3.64% ##
# [  5,  6) 2191   6.23%   9.86% ####
# [  6,  7) 3614  10.27%  20.13% #######
# [  7,  8) 4763  13.53%  33.66% #########
# [  8,  9) 5282  15.01%  48.67% ##########
# [  9, 10) 5138  14.60%  63.27% ##########
# [ 10, 11) 4510  12.81%  76.08% #########
# [ 11, 12) 3437   9.77%  85.85% #######
# [ 12, 13) 2288   6.50%  92.35% ####
# [ 13, 14) 1347   3.83%  96.18% ###
# [ 14, 15)  802   2.28%  98.45% ##
# [ 15, 15]  544   1.55% 100.00% #
#
# Number of training obs by leaf:
# Count: 35196 Average: 64.925 StdDev: 261.118
# Min: 5 Max: 3729 Ignored: 0
# ----------------------------------------------
# [    5,  191) 33291  94.59%  94.59% ##########
# [  191,  377)   685   1.95%  96.53%
# [  377,  563)   257   0.73%  97.26%
# [  563,  750)   157   0.45%  97.71%
# [  750,  936)   173   0.49%  98.20%
# [  936, 1122)   120   0.34%  98.54%
# [ 1122, 1308)    88   0.25%  98.79%
# [ 1308, 1495)    81   0.23%  99.02%
# [ 1495, 1681)    55   0.16%  99.18%
# [ 1681, 1867)    46   0.13%  99.31%
# [ 1867, 2053)    42   0.12%  99.43%
# [ 2053, 2240)    54   0.15%  99.58%
# [ 2240, 2426)    42   0.12%  99.70%
# [ 2426, 2612)    31   0.09%  99.79%
# [ 2612, 2798)    19   0.05%  99.84%
# [ 2798, 2985)    19   0.05%  99.90%
# [ 2985, 3171)    14   0.04%  99.94%
# [ 3171, 3357)     9   0.03%  99.96%
# [ 3357, 3543)    10   0.03%  99.99%
# [ 3543, 3729]     3   0.01% 100.00%
#
# Attribute in nodes:
# 	3663 : LargeDependenceHighGrayLevelEmphasis [NUMERICAL]
# 	3620 : DependenceEntropy [NUMERICAL]
# 	3270 : HighGrayLevelEmphasis [NUMERICAL]
# 	2817 : GrayLevelNonUniformity [NUMERICAL]
# 	2745 : SmallDependenceHighGrayLevelEmphasis [NUMERICAL]
# 	2557 : GrayLevelVariance [NUMERICAL]
# 	2490 : SmallDependenceLowGrayLevelEmphasis [NUMERICAL]
# 	2394 : LowGrayLevelEmphasis [NUMERICAL]
# 	2327 : LargeDependenceLowGrayLevelEmphasis [NUMERICAL]
# 	2083 : SmallDependenceEmphasis [NUMERICAL]
# 	1900 : DependenceVariance [NUMERICAL]
# 	1698 : DependenceNonUniformity [NUMERICAL]
# 	1686 : DependenceNonUniformityNormalized [NUMERICAL]
# 	1646 : LargeDependenceEmphasis [NUMERICAL]
#
# Attribute in nodes with depth <= 0:
# 	108 : HighGrayLevelEmphasis [NUMERICAL]
# 	60 : LargeDependenceHighGrayLevelEmphasis [NUMERICAL]
# 	54 : LowGrayLevelEmphasis [NUMERICAL]
# 	48 : SmallDependenceHighGrayLevelEmphasis [NUMERICAL]
# 	15 : LargeDependenceLowGrayLevelEmphasis [NUMERICAL]
# 	8 : SmallDependenceLowGrayLevelEmphasis [NUMERICAL]
# 	4 : GrayLevelNonUniformity [NUMERICAL]
# 	3 : DependenceEntropy [NUMERICAL]
#
# Attribute in nodes with depth <= 1:
# 	245 : HighGrayLevelEmphasis [NUMERICAL]
# 	194 : LargeDependenceHighGrayLevelEmphasis [NUMERICAL]
# 	135 : LowGrayLevelEmphasis [NUMERICAL]
# 	114 : SmallDependenceHighGrayLevelEmphasis [NUMERICAL]
# 	62 : DependenceEntropy [NUMERICAL]
# 	47 : SmallDependenceLowGrayLevelEmphasis [NUMERICAL]
# 	42 : LargeDependenceLowGrayLevelEmphasis [NUMERICAL]
# 	27 : GrayLevelNonUniformity [NUMERICAL]
# 	8 : SmallDependenceEmphasis [NUMERICAL]
# 	8 : DependenceNonUniformityNormalized [NUMERICAL]
# 	7 : DependenceNonUniformity [NUMERICAL]
# 	5 : LargeDependenceEmphasis [NUMERICAL]
# 	3 : GrayLevelVariance [NUMERICAL]
# 	3 : DependenceVariance [NUMERICAL]
#
# Attribute in nodes with depth <= 2:
# 	455 : HighGrayLevelEmphasis [NUMERICAL]
# 	414 : LargeDependenceHighGrayLevelEmphasis [NUMERICAL]
# 	251 : DependenceEntropy [NUMERICAL]
# 	233 : LowGrayLevelEmphasis [NUMERICAL]
# 	190 : SmallDependenceHighGrayLevelEmphasis [NUMERICAL]
# 	119 : SmallDependenceLowGrayLevelEmphasis [NUMERICAL]
# 	112 : GrayLevelNonUniformity [NUMERICAL]
# 	96 : LargeDependenceLowGrayLevelEmphasis [NUMERICAL]
# 	48 : GrayLevelVariance [NUMERICAL]
# 	39 : SmallDependenceEmphasis [NUMERICAL]
# 	39 : DependenceNonUniformityNormalized [NUMERICAL]
# 	34 : DependenceVariance [NUMERICAL]
# 	31 : DependenceNonUniformity [NUMERICAL]
# 	27 : LargeDependenceEmphasis [NUMERICAL]
#
# Attribute in nodes with depth <= 3:
# 	723 : LargeDependenceHighGrayLevelEmphasis [NUMERICAL]
# 	708 : HighGrayLevelEmphasis [NUMERICAL]
# 	532 : DependenceEntropy [NUMERICAL]
# 	360 : LowGrayLevelEmphasis [NUMERICAL]
# 	328 : SmallDependenceHighGrayLevelEmphasis [NUMERICAL]
# 	296 : GrayLevelNonUniformity [NUMERICAL]
# 	218 : SmallDependenceLowGrayLevelEmphasis [NUMERICAL]
# 	218 : LargeDependenceLowGrayLevelEmphasis [NUMERICAL]
# 	192 : GrayLevelVariance [NUMERICAL]
# 	131 : SmallDependenceEmphasis [NUMERICAL]
# 	129 : DependenceNonUniformityNormalized [NUMERICAL]
# 	116 : DependenceVariance [NUMERICAL]
# 	112 : LargeDependenceEmphasis [NUMERICAL]
# 	112 : DependenceNonUniformity [NUMERICAL]
#
# Attribute in nodes with depth <= 5:
# 	1552 : LargeDependenceHighGrayLevelEmphasis [NUMERICAL]
# 	1394 : HighGrayLevelEmphasis [NUMERICAL]
# 	1389 : DependenceEntropy [NUMERICAL]
# 	955 : GrayLevelNonUniformity [NUMERICAL]
# 	868 : SmallDependenceHighGrayLevelEmphasis [NUMERICAL]
# 	865 : LowGrayLevelEmphasis [NUMERICAL]
# 	731 : GrayLevelVariance [NUMERICAL]
# 	710 : SmallDependenceLowGrayLevelEmphasis [NUMERICAL]
# 	703 : LargeDependenceLowGrayLevelEmphasis [NUMERICAL]
# 	566 : SmallDependenceEmphasis [NUMERICAL]
# 	476 : DependenceVariance [NUMERICAL]
# 	472 : DependenceNonUniformityNormalized [NUMERICAL]
# 	451 : DependenceNonUniformity [NUMERICAL]
# 	437 : LargeDependenceEmphasis [NUMERICAL]
#
# Condition type in nodes:
# 	34896 : HigherCondition
# Condition type in nodes with depth <= 0:
# 	300 : HigherCondition
# Condition type in nodes with depth <= 1:
# 	900 : HigherCondition
# Condition type in nodes with depth <= 2:
# 	2088 : HigherCondition
# Condition type in nodes with depth <= 3:
# 	4175 : HigherCondition
# Condition type in nodes with depth <= 5:
# 	11569 : HigherCondition
# Node format: NOT_SET
#
# Training OOB:
# 	trees: 1, Out-of-bag evaluation: accuracy:0.838026 logloss:5.83814
# 	trees: 11, Out-of-bag evaluation: accuracy:0.843811 logloss:2.25005
# 	trees: 21, Out-of-bag evaluation: accuracy:0.854745 logloss:1.47986
# 	trees: 31, Out-of-bag evaluation: accuracy:0.859598 logloss:1.1921
# 	trees: 41, Out-of-bag evaluation: accuracy:0.86389 logloss:1.08362
# 	trees: 51, Out-of-bag evaluation: accuracy:0.86287 logloss:1.0191
# 	trees: 61, Out-of-bag evaluation: accuracy:0.865472 logloss:0.98172
# 	trees: 71, Out-of-bag evaluation: accuracy:0.867901 logloss:0.843451
# 	trees: 81, Out-of-bag evaluation: accuracy:0.868252 logloss:0.809561
# 	trees: 91, Out-of-bag evaluation: accuracy:0.867302 logloss:0.775573
# 	trees: 101, Out-of-bag evaluation: accuracy:0.867162 logloss:0.709289
# 	trees: 111, Out-of-bag evaluation: accuracy:0.864662 logloss:0.709814
# 	trees: 121, Out-of-bag evaluation: accuracy:0.863852 logloss:0.710061
# 	trees: 131, Out-of-bag evaluation: accuracy:0.866983 logloss:0.644575
# 	trees: 141, Out-of-bag evaluation: accuracy:0.867123 logloss:0.647543
# 	trees: 151, Out-of-bag evaluation: accuracy:0.866033 logloss:0.612081
# 	trees: 161, Out-of-bag evaluation: accuracy:0.865752 logloss:0.609953
# 	trees: 171, Out-of-bag evaluation: accuracy:0.863711 logloss:0.608775
# 	trees: 181, Out-of-bag evaluation: accuracy:0.864942 logloss:0.60893
# 	trees: 191, Out-of-bag evaluation: accuracy:0.866173 logloss:0.575438
# 	trees: 201, Out-of-bag evaluation: accuracy:0.868144 logloss:0.542192
# 	trees: 211, Out-of-bag evaluation: accuracy:0.866103 logloss:0.542137
# 	trees: 221, Out-of-bag evaluation: accuracy:0.863992 logloss:0.54236
# 	trees: 231, Out-of-bag evaluation: accuracy:0.864062 logloss:0.543779
# 	trees: 241, Out-of-bag evaluation: accuracy:0.864343 logloss:0.542332
# 	trees: 251, Out-of-bag evaluation: accuracy:0.864132 logloss:0.510099
# 	trees: 261, Out-of-bag evaluation: accuracy:0.866103 logloss:0.510067
# 	trees: 271, Out-of-bag evaluation: accuracy:0.867123 logloss:0.478387
# 	trees: 281, Out-of-bag evaluation: accuracy:0.866314 logloss:0.477083
# 	trees: 291, Out-of-bag evaluation: accuracy:0.866454 logloss:0.412119
# 	trees: 300, Out-of-bag evaluation: accuracy:0.866314 logloss:0.412653

# %%
# Model features
model.make_inspector().features()
# Out:
# ["DependenceEntropy" (1; #0),
#  "DependenceNonUniformity" (1; #1),
#  "DependenceNonUniformityNormalized" (1; #2),
#  "DependenceVariance" (1; #3),
#  "GrayLevelNonUniformity" (1; #4),
#  "GrayLevelVariance" (1; #5),
#  "HighGrayLevelEmphasis" (1; #6),
#  "LargeDependenceEmphasis" (1; #7),
#  "LargeDependenceHighGrayLevelEmphasis" (1; #8),
#  "LargeDependenceLowGrayLevelEmphasis" (1; #9),
#  "LowGrayLevelEmphasis" (1; #10),
#  "SmallDependenceEmphasis" (1; #11),
#  "SmallDependenceHighGrayLevelEmphasis" (1; #12),
#  "SmallDependenceLowGrayLevelEmphasis" (1; #13)]

# %%
# Feature importance
model.make_inspector().variable_importances()
# Out:
# {'INV_MEAN_MIN_DEPTH': [("LargeDependenceHighGrayLevelEmphasis" (1; #8),
#    0.25101631832900434),
#   ("HighGrayLevelEmphasis" (1; #6), 0.24402020523553777),
#   ("DependenceEntropy" (1; #0), 0.18416636887198143),
#   ("SmallDependenceHighGrayLevelEmphasis" (1; #12), 0.16338253581900125),
#   ("LowGrayLevelEmphasis" (1; #10), 0.15839199303911924),
#   ("GrayLevelNonUniformity" (1; #4), 0.13510003347331126),
#   ("SmallDependenceLowGrayLevelEmphasis" (1; #13), 0.13092386779706922),
#   ("LargeDependenceLowGrayLevelEmphasis" (1; #9), 0.13079828468783222),
#   ("GrayLevelVariance" (1; #5), 0.12174021583575892),
#   ("DependenceNonUniformityNormalized" (1; #2), 0.11934666541698737),
#   ("SmallDependenceEmphasis" (1; #11), 0.11932258557470027),
#   ("DependenceNonUniformity" (1; #1), 0.119014978783195),
#   ("DependenceVariance" (1; #3), 0.11624293221524555),
#   ("LargeDependenceEmphasis" (1; #7), 0.11467575020354605)],
#  'SUM_SCORE': [("HighGrayLevelEmphasis" (1; #6), 353710.4622611508),
#   ("LargeDependenceHighGrayLevelEmphasis" (1; #8), 290368.5211588776),
#   ("SmallDependenceHighGrayLevelEmphasis" (1; #12), 168075.84478666447),
#   ("LowGrayLevelEmphasis" (1; #10), 146412.82962074585),
#   ("DependenceEntropy" (1; #0), 142913.22527282624),
#   ("LargeDependenceLowGrayLevelEmphasis" (1; #9), 72910.52724464798),
#   ("GrayLevelNonUniformity" (1; #4), 70797.42958032036),
#   ("SmallDependenceLowGrayLevelEmphasis" (1; #13), 60074.62829573608),
#   ("GrayLevelVariance" (1; #5), 43372.74257222558),
#   ("SmallDependenceEmphasis" (1; #11), 35894.47443518269),
#   ("DependenceNonUniformityNormalized" (1; #2), 35536.74061407401),
#   ("DependenceNonUniformity" (1; #1), 34034.78581868658),
#   ("DependenceVariance" (1; #3), 30345.621161527608),
#   ("LargeDependenceEmphasis" (1; #7), 26001.98838997671)],
#  'NUM_AS_ROOT': [("HighGrayLevelEmphasis" (1; #6), 108.0),
#   ("LargeDependenceHighGrayLevelEmphasis" (1; #8), 60.0),
#   ("LowGrayLevelEmphasis" (1; #10), 54.0),
#   ("SmallDependenceHighGrayLevelEmphasis" (1; #12), 48.0),
#   ("LargeDependenceLowGrayLevelEmphasis" (1; #9), 15.0),
#   ("SmallDependenceLowGrayLevelEmphasis" (1; #13), 8.0),
#   ("GrayLevelNonUniformity" (1; #4), 4.0),
#   ("DependenceEntropy" (1; #0), 3.0)],
#  'NUM_NODES': [("LargeDependenceHighGrayLevelEmphasis" (1; #8), 3663.0),
#   ("DependenceEntropy" (1; #0), 3620.0),
#   ("HighGrayLevelEmphasis" (1; #6), 3270.0),
#   ("GrayLevelNonUniformity" (1; #4), 2817.0),
#   ("SmallDependenceHighGrayLevelEmphasis" (1; #12), 2745.0),
#   ("GrayLevelVariance" (1; #5), 2557.0),
#   ("SmallDependenceLowGrayLevelEmphasis" (1; #13), 2490.0),
#   ("LowGrayLevelEmphasis" (1; #10), 2394.0),
#   ("LargeDependenceLowGrayLevelEmphasis" (1; #9), 2327.0),
#   ("SmallDependenceEmphasis" (1; #11), 2083.0),
#   ("DependenceVariance" (1; #3), 1900.0),
#   ("DependenceNonUniformity" (1; #1), 1698.0),
#   ("DependenceNonUniformityNormalized" (1; #2), 1686.0),
#   ("LargeDependenceEmphasis" (1; #7), 1646.0)]}

# %%
# Model self evaluation
model.make_inspector().evaluation()
# Out:
# Evaluation(num_examples=7617, accuracy=0.8663135022756026, loss=0.4126532289205864, rmse=None, ndcg=None, aucs=None, auuc=None, qini=None)

# %%
logs = model.make_inspector().training_logs()

plt.figure(figsize=(12, 4))
plt.subplot(1, 2, 1)
plt.plot([log.num_trees for log in logs], [log.evaluation.accuracy for log in logs])
plt.xlabel("Number of trees")
plt.ylabel("Accuracy (out-of-bag)")
plt.subplot(1, 2, 2)
plt.plot([log.num_trees for log in logs], [log.evaluation.loss for log in logs])
plt.xlabel("Number of trees")
plt.ylabel("Logloss (out-of-bag)")
plt.show()

# %% [markdown]
# Calculate the score of our hold-out validation dataset

# %%
predictions = model.predict(val_ds)
y_true      = validation_data["label"]

from sklearn.metrics import roc_auc_score
ROC_AUC = roc_auc_score(y_true, predictions)
print("The ROC AUC score is %.5f" % ROC_AUC )
# Out:
# 1/2 [==============>...............] - ETA: 0s
# 2/2 [==============================] - 0s 4ms/step
# The ROC AUC score is 0.99854

# %%
# Compute binary classification metrics with sklearn
import numpy as np
from sklearn.metrics import (
    accuracy_score,
    precision_score,
    recall_score,
    f1_score,
    roc_auc_score,
    average_precision_score,
    confusion_matrix,
    classification_report,
    matthews_corrcoef,
    log_loss,
    brier_score_loss,
)

# Get predictions (probabilities or class labels)
preds = model.predict(test_ds)
# If model outputs probabilities, convert to labels by threshold 0.5
if preds.ndim == 2:
    # For TFDF classification, preds may be class probabilities with shape (N, 2)
    if preds.shape[1] == 2:
        pos_probs = preds[:, 1]
    else:
        # If single-probability column (positive class)
        pos_probs = preds[:, -1]
    y_pred = (pos_probs >= 0.5).astype(int)
else:
    # Already class labels
    y_pred = preds.astype(int)
    pos_probs = None

# Ground truth labels (must be 0/1 integers)
y_true = test_data["label"].astype(int).to_numpy()

# Core metrics
metrics = {}
metrics["accuracy"] = accuracy_score(y_true, y_pred)
metrics["precision"] = precision_score(y_true, y_pred, zero_division=0)
metrics["recall"] = recall_score(y_true, y_pred, zero_division=0)
metrics["f1"] = f1_score(y_true, y_pred, zero_division=0)
metrics["mcc"] = matthews_corrcoef(y_true, y_pred)

# Probabilistic metrics (only if we have probabilities)
if pos_probs is not None:
    metrics["roc_auc"] = roc_auc_score(y_true, pos_probs)
    metrics["pr_auc"] = average_precision_score(y_true, pos_probs)
    metrics["log_loss"] = log_loss(y_true, pos_probs, labels=[0,1])
    metrics["brier_score"] = brier_score_loss(y_true, pos_probs)

# Confusion matrix and detailed report
cm = confusion_matrix(y_true, y_pred, labels=[0,1])
report = classification_report(y_true, y_pred, digits=4)

print("Sklearn binary metrics:")
for k, v in metrics.items():
    print(f"{k}: {v:.4f}")
print("\nConfusion matrix:\n", cm)
print("\nClassification report:\n", report)
# Out:
# 1/3 [=========>....................] - ETA: 0s
# 3/3 [==============================] - 0s 9ms/step
# Sklearn binary metrics:
# accuracy: 0.9680
# precision: 0.8929
# recall: 0.7709
# f1: 0.8274
# mcc: 0.8126
# roc_auc: 0.9668
# pr_auc: 0.8839
# log_loss: 0.1235
# brier_score: 0.0263
#
# Confusion matrix:
#  [[2035   21]
#  [  52  175]]
#
# Classification report:
#                precision    recall  f1-score   support
#
#            0     0.9751    0.9898    0.9824      2056
#            1     0.8929    0.7709    0.8274       227
#
#     accuracy                         0.9680      2283
#    macro avg     0.9340    0.8804    0.9049      2283
# weighted avg     0.9669    0.9680    0.9670      2283
