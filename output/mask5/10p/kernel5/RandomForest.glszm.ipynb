# %%
# Import packages and modules
import numpy  as np
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow_decision_forests as tfdf

from sklearn.model_selection import train_test_split
# Out:
# 2026-09-12 10:47:40.767148: I tensorflow/core/util/port.cc:113] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2026-09-12 10:47:41.134022: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2026-09-12 10:47:45.832577: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
# Check the version of TensorFlow Decision Forests
print("Found TensorFlow Decision Forests v" + tfdf.__version__)
# Out:
# Found TensorFlow Decision Forests v1.9.1

# %%
datasetPath = "dataset/10p/all/kernel3/"

# %%
# Parameters
datasetPath = "dataset/mask5/10p/glszm/kernel5/"

# %%
# train/validation/test = 70/10/20
train_data = pd.read_csv(f"{datasetPath}dataset.train.csv")
validation_data = pd.read_csv(f"{datasetPath}dataset.validation.csv")
test_data = pd.read_csv(f"{datasetPath}dataset.test.csv")

# %%
from sklearn.utils.class_weight import compute_class_weight

# tinh class weight tren tap train
classes = np.array([0, 1])
weights = compute_class_weight(class_weight="balanced", classes=classes, y=train_data["label"])
class_weight = {0: weights[0], 1: weights[1]}

# gan sample_weight cho tung dong
train_data["sample_weight"] = train_data["label"].map(class_weight)
validation_data["sample_weight"] = validation_data["label"].map(class_weight)
test_data["sample_weight"] = test_data["label"].map(class_weight)

# Convert the dataset into a TensorFlow dataset.
train_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    train_data, label="label", weight="sample_weight"
)         
val_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    validation_data, label="label", weight="sample_weight"
)
test_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    test_data, label="label", weight="sample_weight"
)
# Out:
# 2026-09-12 10:47:59.203998: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:984] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2026-09-12 10:47:59.205568: W tensorflow/core/common_runtime/gpu/gpu_device.cc:2251] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...

# %%
import keras

# %%
# %%time

# Train a Random Forest model.
model = tfdf.keras.RandomForestModel()

# Add evaluation metrics
model.compile(
    metrics=["accuracy"]
)
model.fit(x=train_ds)

# # Train a Gradient Boosted Trees model.
# model = tfdf.keras.GradientBoostedTreesModel(num_trees=1500)
# model.fit(train_ds)
# Out:
# Use /tmp/tmpmrw_g78h as temporary training directory
# Reading training dataset...
# Training dataset read in 0:00:02.608012. Found 7617 examples.
# Training model...
# Model trained in 0:00:00.508216
# Compiling model...
# [INFO 26-09-12 10:48:02.3868 UTC kernel.cc:1233] Loading model from path /tmp/tmpmrw_g78h/model/ with prefix 7cb3272dc3e04d9d
# [INFO 26-09-12 10:48:02.4833 UTC decision_forest.cc:734] Model loaded with 300 root(s), 75820 node(s), and 16 input feature(s).
# [INFO 26-09-12 10:48:02.4833 UTC abstract_model.cc:1362] Engine "RandomForestOptPred" built
# [INFO 26-09-12 10:48:02.4833 UTC kernel.cc:1061] Use fast generic engine
# Model compiled.
# CPU times: user 9.32 s, sys: 204 ms, total: 9.53 s
# Wall time: 6.32 s

# %%
# Evaluate the model
evaluate = model.evaluate(val_ds, return_dict=True)
print()

for name, value in evaluate.items():
    print(f"{name}: {value:.4f}")
# Out:
# WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 1/2 [==============>...............] - ETA: 3s - loss: 0.0000e+00 - accuracy: 0.9870
# 2/2 [==============================] - 3s 9ms/step - loss: 0.0000e+00 - accuracy: 0.9861
# loss: 0.0000
# accuracy: 0.9861

# %%
# Model Summary
model.summary()
# Out:
# Model: "random_forest_model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
# =================================================================
# Total params: 1 (1.00 Byte)
# Trainable params: 0 (0.00 Byte)
# Non-trainable params: 1 (1.00 Byte)
# _________________________________________________________________
# Type: "RANDOM_FOREST"
# Task: CLASSIFICATION
# Label: "__LABEL"
#
# Input Features (16):
# 	GrayLevelNonUniformity
# 	GrayLevelNonUniformityNormalized
# 	GrayLevelVariance
# 	HighGrayLevelZoneEmphasis
# 	LargeAreaEmphasis
# 	LargeAreaHighGrayLevelEmphasis
# 	LargeAreaLowGrayLevelEmphasis
# 	LowGrayLevelZoneEmphasis
# 	SizeZoneNonUniformity
# 	SizeZoneNonUniformityNormalized
# 	SmallAreaEmphasis
# 	SmallAreaHighGrayLevelEmphasis
# 	SmallAreaLowGrayLevelEmphasis
# 	ZoneEntropy
# 	ZonePercentage
# 	ZoneVariance
#
# Trained with weights
#
# Variable Importance: INV_MEAN_MIN_DEPTH:
#     1.        "HighGrayLevelZoneEmphasis"  0.222886 ################
#     2.           "GrayLevelNonUniformity"  0.173830 #########
#     3.   "SmallAreaHighGrayLevelEmphasis"  0.173761 #########
#     4.         "LowGrayLevelZoneEmphasis"  0.157124 ######
#     5.   "LargeAreaHighGrayLevelEmphasis"  0.154169 ######
#     6.    "LargeAreaLowGrayLevelEmphasis"  0.144153 #####
#     7.                      "ZoneEntropy"  0.132497 ###
#     8.    "SmallAreaLowGrayLevelEmphasis"  0.125247 ##
#     9. "GrayLevelNonUniformityNormalized"  0.122948 ##
#    10.                "GrayLevelVariance"  0.118533 #
#    11.                   "ZonePercentage"  0.116647 #
#    12.            "SizeZoneNonUniformity"  0.114397 #
#    13.                     "ZoneVariance"  0.111729
#    14.                "LargeAreaEmphasis"  0.109775
#    15.                "SmallAreaEmphasis"  0.108249
#    16.  "SizeZoneNonUniformityNormalized"  0.106983
#
# Variable Importance: NUM_AS_ROOT:
#     1.        "HighGrayLevelZoneEmphasis" 91.000000 ################
#     2.         "LowGrayLevelZoneEmphasis" 63.000000 ###########
#     3.   "SmallAreaHighGrayLevelEmphasis" 61.000000 ##########
#     4.    "LargeAreaLowGrayLevelEmphasis" 24.000000 ####
#     5.    "SmallAreaLowGrayLevelEmphasis" 20.000000 ###
#     6.                      "ZoneEntropy" 15.000000 ##
#     7. "GrayLevelNonUniformityNormalized"  9.000000 #
#     8.   "LargeAreaHighGrayLevelEmphasis"  9.000000 #
#     9.           "GrayLevelNonUniformity"  5.000000
#    10.                "GrayLevelVariance"  2.000000
#    11.                     "ZoneVariance"  1.000000
#
# Variable Importance: NUM_NODES:
#     1.           "GrayLevelNonUniformity" 3040.000000 ################
#     2.        "HighGrayLevelZoneEmphasis" 2981.000000 ###############
#     3.   "LargeAreaHighGrayLevelEmphasis" 2944.000000 ##############
#     4.    "LargeAreaLowGrayLevelEmphasis" 2866.000000 #############
#     5.   "SmallAreaHighGrayLevelEmphasis" 2829.000000 #############
#     6.                      "ZoneEntropy" 2659.000000 ###########
#     7.         "LowGrayLevelZoneEmphasis" 2469.000000 #########
#     8.                "GrayLevelVariance" 2444.000000 ########
#     9. "GrayLevelNonUniformityNormalized" 2408.000000 ########
#    10.    "SmallAreaLowGrayLevelEmphasis" 2135.000000 #####
#    11.                     "ZoneVariance" 1982.000000 ###
#    12.            "SizeZoneNonUniformity" 1897.000000 ##
#    13.                   "ZonePercentage" 1846.000000 #
#    14.                "LargeAreaEmphasis" 1819.000000 #
#    15.                "SmallAreaEmphasis" 1762.000000
#    16.  "SizeZoneNonUniformityNormalized" 1679.000000
#
# Variable Importance: SUM_SCORE:
#     1.        "HighGrayLevelZoneEmphasis" 316090.891589 ################
#     2.   "SmallAreaHighGrayLevelEmphasis" 222528.090415 ##########
#     3.         "LowGrayLevelZoneEmphasis" 176545.900854 ########
#     4.           "GrayLevelNonUniformity" 132499.878438 #####
#     5.   "LargeAreaHighGrayLevelEmphasis" 105049.404347 ####
#     6.    "LargeAreaLowGrayLevelEmphasis" 96918.864600 ####
#     7.                      "ZoneEntropy" 83051.639702 ###
#     8.    "SmallAreaLowGrayLevelEmphasis" 79524.142135 ###
#     9. "GrayLevelNonUniformityNormalized" 52802.081045 #
#    10.                "GrayLevelVariance" 43416.095667 #
#    11.                   "ZonePercentage" 38417.479593
#    12.                     "ZoneVariance" 35913.473806
#    13.            "SizeZoneNonUniformity" 34624.904913
#    14.                "LargeAreaEmphasis" 31127.185772
#    15.                "SmallAreaEmphasis" 24406.353700
#    16.  "SizeZoneNonUniformityNormalized" 23691.707845
#
#
#
# Winner takes all: true
# Out-of-bag evaluation: accuracy:0.853405 logloss:0.41493
# Number of trees: 300
# Total number of nodes: 75820
#
# Number of nodes by tree:
# Count: 300 Average: 252.733 StdDev: 13.8904
# Min: 221 Max: 293 Ignored: 0
# ----------------------------------------------
# [ 221, 224)  4   1.33%   1.33% #
# [ 224, 228) 10   3.33%   4.67% ##
# [ 228, 231)  6   2.00%   6.67% #
# [ 231, 235) 10   3.33%  10.00% ##
# [ 235, 239) 14   4.67%  14.67% ###
# [ 239, 242) 17   5.67%  20.33% ####
# [ 242, 246) 30  10.00%  30.33% #######
# [ 246, 250) 29   9.67%  40.00% #######
# [ 250, 253) 15   5.00%  45.00% ###
# [ 253, 257) 44  14.67%  59.67% ##########
# [ 257, 261) 42  14.00%  73.67% ##########
# [ 261, 264) 21   7.00%  80.67% #####
# [ 264, 268) 17   5.67%  86.33% ####
# [ 268, 272) 17   5.67%  92.00% ####
# [ 272, 275)  8   2.67%  94.67% ##
# [ 275, 279)  6   2.00%  96.67% #
# [ 279, 283)  3   1.00%  97.67% #
# [ 283, 286)  1   0.33%  98.00%
# [ 286, 290)  4   1.33%  99.33% #
# [ 290, 293]  2   0.67% 100.00%
#
# Depth by leafs:
# Count: 38060 Average: 9.2557 StdDev: 2.81197
# Min: 2 Max: 15 Ignored: 0
# ----------------------------------------------
# [  2,  3)   29   0.08%   0.08%
# [  3,  4)  350   0.92%   1.00% #
# [  4,  5) 1049   2.76%   3.75% ##
# [  5,  6) 2034   5.34%   9.10% ####
# [  6,  7) 3199   8.41%  17.50% ######
# [  7,  8) 4260  11.19%  28.69% ########
# [  8,  9) 4895  12.86%  41.56% ##########
# [  9, 10) 5052  13.27%  54.83% ##########
# [ 10, 11) 4605  12.10%  66.93% #########
# [ 11, 12) 3878  10.19%  77.12% ########
# [ 12, 13) 3256   8.55%  85.67% ######
# [ 13, 14) 2400   6.31%  91.98% #####
# [ 14, 15) 1619   4.25%  96.23% ###
# [ 15, 15] 1434   3.77% 100.00% ###
#
# Number of training obs by leaf:
# Count: 38060 Average: 60.0394 StdDev: 213.128
# Min: 5 Max: 3082 Ignored: 0
# ----------------------------------------------
# [    5,  158) 35441  93.12%  93.12% ##########
# [  158,  312)   996   2.62%  95.74%
# [  312,  466)   454   1.19%  96.93%
# [  466,  620)   252   0.66%  97.59%
# [  620,  774)   206   0.54%  98.13%
# [  774,  928)   165   0.43%  98.57%
# [  928, 1082)   102   0.27%  98.83%
# [ 1082, 1236)    79   0.21%  99.04%
# [ 1236, 1390)    70   0.18%  99.22%
# [ 1390, 1544)    51   0.13%  99.36%
# [ 1544, 1697)    51   0.13%  99.49%
# [ 1697, 1851)    61   0.16%  99.65%
# [ 1851, 2005)    36   0.09%  99.75%
# [ 2005, 2159)    26   0.07%  99.82%
# [ 2159, 2313)    30   0.08%  99.89%
# [ 2313, 2467)    17   0.04%  99.94%
# [ 2467, 2621)    10   0.03%  99.97%
# [ 2621, 2775)     7   0.02%  99.98%
# [ 2775, 2929)     4   0.01%  99.99%
# [ 2929, 3082]     2   0.01% 100.00%
#
# Attribute in nodes:
# 	3040 : GrayLevelNonUniformity [NUMERICAL]
# 	2981 : HighGrayLevelZoneEmphasis [NUMERICAL]
# 	2944 : LargeAreaHighGrayLevelEmphasis [NUMERICAL]
# 	2866 : LargeAreaLowGrayLevelEmphasis [NUMERICAL]
# 	2829 : SmallAreaHighGrayLevelEmphasis [NUMERICAL]
# 	2659 : ZoneEntropy [NUMERICAL]
# 	2469 : LowGrayLevelZoneEmphasis [NUMERICAL]
# 	2444 : GrayLevelVariance [NUMERICAL]
# 	2408 : GrayLevelNonUniformityNormalized [NUMERICAL]
# 	2135 : SmallAreaLowGrayLevelEmphasis [NUMERICAL]
# 	1982 : ZoneVariance [NUMERICAL]
# 	1897 : SizeZoneNonUniformity [NUMERICAL]
# 	1846 : ZonePercentage [NUMERICAL]
# 	1819 : LargeAreaEmphasis [NUMERICAL]
# 	1762 : SmallAreaEmphasis [NUMERICAL]
# 	1679 : SizeZoneNonUniformityNormalized [NUMERICAL]
#
# Attribute in nodes with depth <= 0:
# 	91 : HighGrayLevelZoneEmphasis [NUMERICAL]
# 	63 : LowGrayLevelZoneEmphasis [NUMERICAL]
# 	61 : SmallAreaHighGrayLevelEmphasis [NUMERICAL]
# 	24 : LargeAreaLowGrayLevelEmphasis [NUMERICAL]
# 	20 : SmallAreaLowGrayLevelEmphasis [NUMERICAL]
# 	15 : ZoneEntropy [NUMERICAL]
# 	9 : LargeAreaHighGrayLevelEmphasis [NUMERICAL]
# 	9 : GrayLevelNonUniformityNormalized [NUMERICAL]
# 	5 : GrayLevelNonUniformity [NUMERICAL]
# 	2 : GrayLevelVariance [NUMERICAL]
# 	1 : ZoneVariance [NUMERICAL]
#
# Attribute in nodes with depth <= 1:
# 	234 : HighGrayLevelZoneEmphasis [NUMERICAL]
# 	144 : LowGrayLevelZoneEmphasis [NUMERICAL]
# 	140 : SmallAreaHighGrayLevelEmphasis [NUMERICAL]
# 	74 : SmallAreaLowGrayLevelEmphasis [NUMERICAL]
# 	74 : GrayLevelNonUniformity [NUMERICAL]
# 	66 : LargeAreaHighGrayLevelEmphasis [NUMERICAL]
# 	42 : LargeAreaLowGrayLevelEmphasis [NUMERICAL]
# 	36 : ZoneEntropy [NUMERICAL]
# 	33 : ZonePercentage [NUMERICAL]
# 	18 : GrayLevelNonUniformityNormalized [NUMERICAL]
# 	13 : SizeZoneNonUniformity [NUMERICAL]
# 	9 : GrayLevelVariance [NUMERICAL]
# 	6 : LargeAreaEmphasis [NUMERICAL]
# 	5 : SmallAreaEmphasis [NUMERICAL]
# 	3 : ZoneVariance [NUMERICAL]
# 	3 : SizeZoneNonUniformityNormalized [NUMERICAL]
#
# Attribute in nodes with depth <= 2:
# 	387 : HighGrayLevelZoneEmphasis [NUMERICAL]
# 	255 : LowGrayLevelZoneEmphasis [NUMERICAL]
# 	240 : SmallAreaHighGrayLevelEmphasis [NUMERICAL]
# 	215 : GrayLevelNonUniformity [NUMERICAL]
# 	186 : LargeAreaHighGrayLevelEmphasis [NUMERICAL]
# 	151 : SmallAreaLowGrayLevelEmphasis [NUMERICAL]
# 	148 : LargeAreaLowGrayLevelEmphasis [NUMERICAL]
# 	120 : ZoneEntropy [NUMERICAL]
# 	69 : ZonePercentage [NUMERICAL]
# 	65 : GrayLevelNonUniformityNormalized [NUMERICAL]
# 	58 : GrayLevelVariance [NUMERICAL]
# 	52 : SizeZoneNonUniformity [NUMERICAL]
# 	36 : ZoneVariance [NUMERICAL]
# 	34 : LargeAreaEmphasis [NUMERICAL]
# 	28 : SizeZoneNonUniformityNormalized [NUMERICAL]
# 	27 : SmallAreaEmphasis [NUMERICAL]
#
# Attribute in nodes with depth <= 3:
# 	609 : HighGrayLevelZoneEmphasis [NUMERICAL]
# 	433 : GrayLevelNonUniformity [NUMERICAL]
# 	405 : SmallAreaHighGrayLevelEmphasis [NUMERICAL]
# 	391 : LowGrayLevelZoneEmphasis [NUMERICAL]
# 	363 : LargeAreaHighGrayLevelEmphasis [NUMERICAL]
# 	312 : LargeAreaLowGrayLevelEmphasis [NUMERICAL]
# 	272 : ZoneEntropy [NUMERICAL]
# 	254 : SmallAreaLowGrayLevelEmphasis [NUMERICAL]
# 	193 : GrayLevelVariance [NUMERICAL]
# 	179 : GrayLevelNonUniformityNormalized [NUMERICAL]
# 	144 : ZonePercentage [NUMERICAL]
# 	126 : ZoneVariance [NUMERICAL]
# 	116 : SizeZoneNonUniformity [NUMERICAL]
# 	115 : LargeAreaEmphasis [NUMERICAL]
# 	79 : SmallAreaEmphasis [NUMERICAL]
# 	72 : SizeZoneNonUniformityNormalized [NUMERICAL]
#
# Attribute in nodes with depth <= 5:
# 	1141 : HighGrayLevelZoneEmphasis [NUMERICAL]
# 	1038 : GrayLevelNonUniformity [NUMERICAL]
# 	916 : SmallAreaHighGrayLevelEmphasis [NUMERICAL]
# 	862 : LargeAreaHighGrayLevelEmphasis [NUMERICAL]
# 	830 : LowGrayLevelZoneEmphasis [NUMERICAL]
# 	827 : LargeAreaLowGrayLevelEmphasis [NUMERICAL]
# 	816 : ZoneEntropy [NUMERICAL]
# 	618 : GrayLevelNonUniformityNormalized [NUMERICAL]
# 	611 : GrayLevelVariance [NUMERICAL]
# 	606 : SmallAreaLowGrayLevelEmphasis [NUMERICAL]
# 	500 : ZoneVariance [NUMERICAL]
# 	464 : ZonePercentage [NUMERICAL]
# 	442 : LargeAreaEmphasis [NUMERICAL]
# 	436 : SizeZoneNonUniformity [NUMERICAL]
# 	366 : SmallAreaEmphasis [NUMERICAL]
# 	361 : SizeZoneNonUniformityNormalized [NUMERICAL]
#
# Condition type in nodes:
# 	37760 : HigherCondition
# Condition type in nodes with depth <= 0:
# 	300 : HigherCondition
# Condition type in nodes with depth <= 1:
# 	900 : HigherCondition
# Condition type in nodes with depth <= 2:
# 	2071 : HigherCondition
# Condition type in nodes with depth <= 3:
# 	4063 : HigherCondition
# Condition type in nodes with depth <= 5:
# 	10834 : HigherCondition
# Node format: NOT_SET
#
# Training OOB:
# 	trees: 1, Out-of-bag evaluation: accuracy:0.847536 logloss:5.49537
# 	trees: 11, Out-of-bag evaluation: accuracy:0.830841 logloss:2.5794
# 	trees: 21, Out-of-bag evaluation: accuracy:0.844119 logloss:1.49411
# 	trees: 31, Out-of-bag evaluation: accuracy:0.840988 logloss:0.932397
# 	trees: 41, Out-of-bag evaluation: accuracy:0.84257 logloss:0.749717
# 	trees: 51, Out-of-bag evaluation: accuracy:0.847002 logloss:0.745925
# 	trees: 61, Out-of-bag evaluation: accuracy:0.851154 logloss:0.609793
# 	trees: 71, Out-of-bag evaluation: accuracy:0.851435 logloss:0.545693
# 	trees: 81, Out-of-bag evaluation: accuracy:0.847952 logloss:0.543503
# 	trees: 91, Out-of-bag evaluation: accuracy:0.849043 logloss:0.544948
# 	trees: 101, Out-of-bag evaluation: accuracy:0.846792 logloss:0.546037
# 	trees: 111, Out-of-bag evaluation: accuracy:0.849113 logloss:0.547886
# 	trees: 121, Out-of-bag evaluation: accuracy:0.851224 logloss:0.516158
# 	trees: 131, Out-of-bag evaluation: accuracy:0.851964 logloss:0.515229
# 	trees: 141, Out-of-bag evaluation: accuracy:0.854145 logloss:0.516432
# 	trees: 151, Out-of-bag evaluation: accuracy:0.853265 logloss:0.515546
# 	trees: 161, Out-of-bag evaluation: accuracy:0.851505 logloss:0.513743
# 	trees: 171, Out-of-bag evaluation: accuracy:0.854145 logloss:0.513769
# 	trees: 181, Out-of-bag evaluation: accuracy:0.855376 logloss:0.480527
# 	trees: 191, Out-of-bag evaluation: accuracy:0.854636 logloss:0.479409
# 	trees: 201, Out-of-bag evaluation: accuracy:0.853616 logloss:0.446419
# 	trees: 211, Out-of-bag evaluation: accuracy:0.854706 logloss:0.44499
# 	trees: 221, Out-of-bag evaluation: accuracy:0.854776 logloss:0.443953
# 	trees: 231, Out-of-bag evaluation: accuracy:0.851715 logloss:0.411716
# 	trees: 241, Out-of-bag evaluation: accuracy:0.852595 logloss:0.412851
# 	trees: 251, Out-of-bag evaluation: accuracy:0.851715 logloss:0.413859
# 	trees: 261, Out-of-bag evaluation: accuracy:0.849745 logloss:0.415493
# 	trees: 271, Out-of-bag evaluation: accuracy:0.852455 logloss:0.416223
# 	trees: 281, Out-of-bag evaluation: accuracy:0.852525 logloss:0.416762
# 	trees: 291, Out-of-bag evaluation: accuracy:0.851435 logloss:0.415495
# 	trees: 300, Out-of-bag evaluation: accuracy:0.853405 logloss:0.41493

# %%
# Model features
model.make_inspector().features()
# Out:
# ["GrayLevelNonUniformity" (1; #0),
#  "GrayLevelNonUniformityNormalized" (1; #1),
#  "GrayLevelVariance" (1; #2),
#  "HighGrayLevelZoneEmphasis" (1; #3),
#  "LargeAreaEmphasis" (1; #4),
#  "LargeAreaHighGrayLevelEmphasis" (1; #5),
#  "LargeAreaLowGrayLevelEmphasis" (1; #6),
#  "LowGrayLevelZoneEmphasis" (1; #7),
#  "SizeZoneNonUniformity" (1; #8),
#  "SizeZoneNonUniformityNormalized" (1; #9),
#  "SmallAreaEmphasis" (1; #10),
#  "SmallAreaHighGrayLevelEmphasis" (1; #11),
#  "SmallAreaLowGrayLevelEmphasis" (1; #12),
#  "ZoneEntropy" (1; #13),
#  "ZonePercentage" (1; #14),
#  "ZoneVariance" (1; #15)]

# %%
# Feature importance
model.make_inspector().variable_importances()
# Out:
# {'INV_MEAN_MIN_DEPTH': [("HighGrayLevelZoneEmphasis" (1; #3),
#    0.22288578785087998),
#   ("GrayLevelNonUniformity" (1; #0), 0.17382958843305213),
#   ("SmallAreaHighGrayLevelEmphasis" (1; #11), 0.17376104335592732),
#   ("LowGrayLevelZoneEmphasis" (1; #7), 0.1571241614587893),
#   ("LargeAreaHighGrayLevelEmphasis" (1; #5), 0.15416928653927695),
#   ("LargeAreaLowGrayLevelEmphasis" (1; #6), 0.1441529572228003),
#   ("ZoneEntropy" (1; #13), 0.13249685466684982),
#   ("SmallAreaLowGrayLevelEmphasis" (1; #12), 0.12524741894579217),
#   ("GrayLevelNonUniformityNormalized" (1; #1), 0.1229475951830809),
#   ("GrayLevelVariance" (1; #2), 0.11853282038399088),
#   ("ZonePercentage" (1; #14), 0.11664743615420683),
#   ("SizeZoneNonUniformity" (1; #8), 0.11439703764569004),
#   ("ZoneVariance" (1; #15), 0.1117288592574465),
#   ("LargeAreaEmphasis" (1; #4), 0.10977490386957715),
#   ("SmallAreaEmphasis" (1; #10), 0.10824942750413631),
#   ("SizeZoneNonUniformityNormalized" (1; #9), 0.10698250591173135)],
#  'NUM_AS_ROOT': [("HighGrayLevelZoneEmphasis" (1; #3), 91.0),
#   ("LowGrayLevelZoneEmphasis" (1; #7), 63.0),
#   ("SmallAreaHighGrayLevelEmphasis" (1; #11), 61.0),
#   ("LargeAreaLowGrayLevelEmphasis" (1; #6), 24.0),
#   ("SmallAreaLowGrayLevelEmphasis" (1; #12), 20.0),
#   ("ZoneEntropy" (1; #13), 15.0),
#   ("GrayLevelNonUniformityNormalized" (1; #1), 9.0),
#   ("LargeAreaHighGrayLevelEmphasis" (1; #5), 9.0),
#   ("GrayLevelNonUniformity" (1; #0), 5.0),
#   ("GrayLevelVariance" (1; #2), 2.0),
#   ("ZoneVariance" (1; #15), 1.0)],
#  'SUM_SCORE': [("HighGrayLevelZoneEmphasis" (1; #3), 316090.8915889684),
#   ("SmallAreaHighGrayLevelEmphasis" (1; #11), 222528.0904145806),
#   ("LowGrayLevelZoneEmphasis" (1; #7), 176545.90085425702),
#   ("GrayLevelNonUniformity" (1; #0), 132499.878437984),
#   ("LargeAreaHighGrayLevelEmphasis" (1; #5), 105049.40434722127),
#   ("LargeAreaLowGrayLevelEmphasis" (1; #6), 96918.86460000336),
#   ("ZoneEntropy" (1; #13), 83051.63970155115),
#   ("SmallAreaLowGrayLevelEmphasis" (1; #12), 79524.14213510485),
#   ("GrayLevelNonUniformityNormalized" (1; #1), 52802.08104496805),
#   ("GrayLevelVariance" (1; #2), 43416.0956670013),
#   ("ZonePercentage" (1; #14), 38417.47959326727),
#   ("ZoneVariance" (1; #15), 35913.473805893744),
#   ("SizeZoneNonUniformity" (1; #8), 34624.90491264832),
#   ("LargeAreaEmphasis" (1; #4), 31127.185771736404),
#   ("SmallAreaEmphasis" (1; #10), 24406.35370023707),
#   ("SizeZoneNonUniformityNormalized" (1; #9), 23691.707845107798)],
#  'NUM_NODES': [("GrayLevelNonUniformity" (1; #0), 3040.0),
#   ("HighGrayLevelZoneEmphasis" (1; #3), 2981.0),
#   ("LargeAreaHighGrayLevelEmphasis" (1; #5), 2944.0),
#   ("LargeAreaLowGrayLevelEmphasis" (1; #6), 2866.0),
#   ("SmallAreaHighGrayLevelEmphasis" (1; #11), 2829.0),
#   ("ZoneEntropy" (1; #13), 2659.0),
#   ("LowGrayLevelZoneEmphasis" (1; #7), 2469.0),
#   ("GrayLevelVariance" (1; #2), 2444.0),
#   ("GrayLevelNonUniformityNormalized" (1; #1), 2408.0),
#   ("SmallAreaLowGrayLevelEmphasis" (1; #12), 2135.0),
#   ("ZoneVariance" (1; #15), 1982.0),
#   ("SizeZoneNonUniformity" (1; #8), 1897.0),
#   ("ZonePercentage" (1; #14), 1846.0),
#   ("LargeAreaEmphasis" (1; #4), 1819.0),
#   ("SmallAreaEmphasis" (1; #10), 1762.0),
#   ("SizeZoneNonUniformityNormalized" (1; #9), 1679.0)]}

# %%
# Model self evaluation
model.make_inspector().evaluation()
# Out:
# Evaluation(num_examples=7617, accuracy=0.8534052746285105, loss=0.41492954670631776, rmse=None, ndcg=None, aucs=None, auuc=None, qini=None)

# %%
logs = model.make_inspector().training_logs()

plt.figure(figsize=(12, 4))
plt.subplot(1, 2, 1)
plt.plot([log.num_trees for log in logs], [log.evaluation.accuracy for log in logs])
plt.xlabel("Number of trees")
plt.ylabel("Accuracy (out-of-bag)")
plt.subplot(1, 2, 2)
plt.plot([log.num_trees for log in logs], [log.evaluation.loss for log in logs])
plt.xlabel("Number of trees")
plt.ylabel("Logloss (out-of-bag)")
plt.show()

# %% [markdown]
# Calculate the score of our hold-out validation dataset

# %%
predictions = model.predict(val_ds)
y_true      = validation_data["label"]

from sklearn.metrics import roc_auc_score
ROC_AUC = roc_auc_score(y_true, predictions)
print("The ROC AUC score is %.5f" % ROC_AUC )
# Out:
# 1/2 [==============>...............] - ETA: 0s
# 2/2 [==============================] - 0s 4ms/step
# The ROC AUC score is 0.99789

# %%
# Compute binary classification metrics with sklearn
import numpy as np
from sklearn.metrics import (
    accuracy_score,
    precision_score,
    recall_score,
    f1_score,
    roc_auc_score,
    average_precision_score,
    confusion_matrix,
    classification_report,
    matthews_corrcoef,
    log_loss,
    brier_score_loss,
)

# Get predictions (probabilities or class labels)
preds = model.predict(test_ds)
# If model outputs probabilities, convert to labels by threshold 0.5
if preds.ndim == 2:
    # For TFDF classification, preds may be class probabilities with shape (N, 2)
    if preds.shape[1] == 2:
        pos_probs = preds[:, 1]
    else:
        # If single-probability column (positive class)
        pos_probs = preds[:, -1]
    y_pred = (pos_probs >= 0.5).astype(int)
else:
    # Already class labels
    y_pred = preds.astype(int)
    pos_probs = None

# Ground truth labels (must be 0/1 integers)
y_true = test_data["label"].astype(int).to_numpy()

# Core metrics
metrics = {}
metrics["accuracy"] = accuracy_score(y_true, y_pred)
metrics["precision"] = precision_score(y_true, y_pred, zero_division=0)
metrics["recall"] = recall_score(y_true, y_pred, zero_division=0)
metrics["f1"] = f1_score(y_true, y_pred, zero_division=0)
metrics["mcc"] = matthews_corrcoef(y_true, y_pred)

# Probabilistic metrics (only if we have probabilities)
if pos_probs is not None:
    metrics["roc_auc"] = roc_auc_score(y_true, pos_probs)
    metrics["pr_auc"] = average_precision_score(y_true, pos_probs)
    metrics["log_loss"] = log_loss(y_true, pos_probs, labels=[0,1])
    metrics["brier_score"] = brier_score_loss(y_true, pos_probs)

# Confusion matrix and detailed report
cm = confusion_matrix(y_true, y_pred, labels=[0,1])
report = classification_report(y_true, y_pred, digits=4)

print("Sklearn binary metrics:")
for k, v in metrics.items():
    print(f"{k}: {v:.4f}")
print("\nConfusion matrix:\n", cm)
print("\nClassification report:\n", report)
# Out:
# 1/3 [=========>....................] - ETA: 0s
# 3/3 [==============================] - 0s 10ms/step
# Sklearn binary metrics:
# accuracy: 0.9615
# precision: 0.8717
# recall: 0.7181
# f1: 0.7874
# mcc: 0.7708
# roc_auc: 0.9715
# pr_auc: 0.8669
# log_loss: 0.1137
# brier_score: 0.0300
#
# Confusion matrix:
#  [[2032   24]
#  [  64  163]]
#
# Classification report:
#                precision    recall  f1-score   support
#
#            0     0.9695    0.9883    0.9788      2056
#            1     0.8717    0.7181    0.7874       227
#
#     accuracy                         0.9615      2283
#    macro avg     0.9206    0.8532    0.8831      2283
# weighted avg     0.9597    0.9615    0.9598      2283
