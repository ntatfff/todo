# %%
# Import packages and modules
import numpy  as np
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow_decision_forests as tfdf

from sklearn.model_selection import train_test_split
# Out:
# 2026-09-12 10:47:04.975517: I tensorflow/core/util/port.cc:113] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2026-09-12 10:47:05.349754: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2026-09-12 10:47:10.061746: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
# Check the version of TensorFlow Decision Forests
print("Found TensorFlow Decision Forests v" + tfdf.__version__)
# Out:
# Found TensorFlow Decision Forests v1.9.1

# %%
datasetPath = "dataset/10p/all/kernel3/"

# %%
# Parameters
datasetPath = "dataset/mask5/10p/glrlm/kernel5/"

# %%
# train/validation/test = 70/10/20
train_data = pd.read_csv(f"{datasetPath}dataset.train.csv")
validation_data = pd.read_csv(f"{datasetPath}dataset.validation.csv")
test_data = pd.read_csv(f"{datasetPath}dataset.test.csv")

# %%
from sklearn.utils.class_weight import compute_class_weight

# tinh class weight tren tap train
classes = np.array([0, 1])
weights = compute_class_weight(class_weight="balanced", classes=classes, y=train_data["label"])
class_weight = {0: weights[0], 1: weights[1]}

# gan sample_weight cho tung dong
train_data["sample_weight"] = train_data["label"].map(class_weight)
validation_data["sample_weight"] = validation_data["label"].map(class_weight)
test_data["sample_weight"] = test_data["label"].map(class_weight)

# Convert the dataset into a TensorFlow dataset.
train_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    train_data, label="label", weight="sample_weight"
)         
val_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    validation_data, label="label", weight="sample_weight"
)
test_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    test_data, label="label", weight="sample_weight"
)
# Out:
# 2026-09-12 10:47:23.592370: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:984] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2026-09-12 10:47:23.593872: W tensorflow/core/common_runtime/gpu/gpu_device.cc:2251] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...

# %%
import keras

# %%
# %%time

# Train a Random Forest model.
model = tfdf.keras.RandomForestModel()

# Add evaluation metrics
model.compile(
    metrics=["accuracy"]
)
model.fit(x=train_ds)

# # Train a Gradient Boosted Trees model.
# model = tfdf.keras.GradientBoostedTreesModel(num_trees=1500)
# model.fit(train_ds)
# Out:
# Use /tmp/tmp7nxga7do as temporary training directory
# Reading training dataset...
# Training dataset read in 0:00:02.645393. Found 7617 examples.
# Training model...
# Model trained in 0:00:00.519177
# Compiling model...
# [INFO 26-09-12 10:47:26.8120 UTC kernel.cc:1233] Loading model from path /tmp/tmp7nxga7do/model/ with prefix 5be5ba00609a455c
# [INFO 26-09-12 10:47:26.9075 UTC decision_forest.cc:734] Model loaded with 300 root(s), 75340 node(s), and 16 input feature(s).
# [INFO 26-09-12 10:47:26.9075 UTC abstract_model.cc:1362] Engine "RandomForestOptPred" built
# [INFO 26-09-12 10:47:26.9076 UTC kernel.cc:1061] Use fast generic engine
# Model compiled.
# CPU times: user 9.43 s, sys: 218 ms, total: 9.65 s
# Wall time: 6.36 s

# %%
# Evaluate the model
evaluate = model.evaluate(val_ds, return_dict=True)
print()

for name, value in evaluate.items():
    print(f"{name}: {value:.4f}")
# Out:
# WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 1/2 [==============>...............] - ETA: 2s - loss: 0.0000e+00 - accuracy: 0.9880
# 2/2 [==============================] - 3s 9ms/step - loss: 0.0000e+00 - accuracy: 0.9888
# loss: 0.0000
# accuracy: 0.9888

# %%
# Model Summary
model.summary()
# Out:
# Model: "random_forest_model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
# =================================================================
# Total params: 1 (1.00 Byte)
# Trainable params: 0 (0.00 Byte)
# Non-trainable params: 1 (1.00 Byte)
# _________________________________________________________________
# Type: "RANDOM_FOREST"
# Task: CLASSIFICATION
# Label: "__LABEL"
#
# Input Features (16):
# 	GrayLevelNonUniformity
# 	GrayLevelNonUniformityNormalized
# 	GrayLevelVariance
# 	HighGrayLevelRunEmphasis
# 	LongRunEmphasis
# 	LongRunHighGrayLevelEmphasis
# 	LongRunLowGrayLevelEmphasis
# 	LowGrayLevelRunEmphasis
# 	RunEntropy
# 	RunLengthNonUniformity
# 	RunLengthNonUniformityNormalized
# 	RunPercentage
# 	RunVariance
# 	ShortRunEmphasis
# 	ShortRunHighGrayLevelEmphasis
# 	ShortRunLowGrayLevelEmphasis
#
# Trained with weights
#
# Variable Importance: INV_MEAN_MIN_DEPTH:
#     1.     "LongRunHighGrayLevelEmphasis"  0.282968 ################
#     2.         "HighGrayLevelRunEmphasis"  0.174570 #####
#     3.    "ShortRunHighGrayLevelEmphasis"  0.165017 ####
#     4.     "ShortRunLowGrayLevelEmphasis"  0.139725 ##
#     5.          "LowGrayLevelRunEmphasis"  0.133234 #
#     6.      "LongRunLowGrayLevelEmphasis"  0.132828 #
#     7.                       "RunEntropy"  0.125833 #
#     8.                      "RunVariance"  0.120399
#     9.           "GrayLevelNonUniformity"  0.119297
#    10. "RunLengthNonUniformityNormalized"  0.119228
#    11.                 "ShortRunEmphasis"  0.117836
#    12.                  "LongRunEmphasis"  0.117554
#    13.                    "RunPercentage"  0.115079
#    14. "GrayLevelNonUniformityNormalized"  0.114314
#    15.                "GrayLevelVariance"  0.113639
#    16.           "RunLengthNonUniformity"  0.112637
#
# Variable Importance: NUM_AS_ROOT:
#     1.     "LongRunHighGrayLevelEmphasis" 101.000000 ################
#     2.    "ShortRunHighGrayLevelEmphasis" 55.000000 ########
#     3.         "HighGrayLevelRunEmphasis" 52.000000 ########
#     4.     "ShortRunLowGrayLevelEmphasis" 41.000000 ######
#     5.          "LowGrayLevelRunEmphasis" 26.000000 ####
#     6.      "LongRunLowGrayLevelEmphasis" 14.000000 ##
#     7. "GrayLevelNonUniformityNormalized"  4.000000
#     8.           "GrayLevelNonUniformity"  3.000000
#     9.                       "RunEntropy"  3.000000
#    10.                      "RunVariance"  1.000000
#
# Variable Importance: NUM_NODES:
#     1.     "LongRunHighGrayLevelEmphasis" 3487.000000 ################
#     2.                       "RunEntropy" 3229.000000 #############
#     3.           "GrayLevelNonUniformity" 2675.000000 #########
#     4.                "GrayLevelVariance" 2668.000000 #########
#     5.         "HighGrayLevelRunEmphasis" 2621.000000 ########
#     6. "GrayLevelNonUniformityNormalized" 2515.000000 #######
#     7.    "ShortRunHighGrayLevelEmphasis" 2513.000000 #######
#     8.      "LongRunLowGrayLevelEmphasis" 2414.000000 #######
#     9.     "ShortRunLowGrayLevelEmphasis" 2414.000000 #######
#    10.          "LowGrayLevelRunEmphasis" 2355.000000 ######
#    11.                      "RunVariance" 2075.000000 ####
#    12. "RunLengthNonUniformityNormalized" 1818.000000 ##
#    13.                  "LongRunEmphasis" 1777.000000 #
#    14.                 "ShortRunEmphasis" 1756.000000 #
#    15.           "RunLengthNonUniformity" 1631.000000
#    16.                    "RunPercentage" 1572.000000
#
# Variable Importance: SUM_SCORE:
#     1.     "LongRunHighGrayLevelEmphasis" 383062.616317 ################
#     2.         "HighGrayLevelRunEmphasis" 188001.392086 #######
#     3.    "ShortRunHighGrayLevelEmphasis" 184536.641440 ######
#     4.     "ShortRunLowGrayLevelEmphasis" 122724.645604 ####
#     5.          "LowGrayLevelRunEmphasis" 94002.815538 ##
#     6.      "LongRunLowGrayLevelEmphasis" 79221.571855 ##
#     7.                       "RunEntropy" 77272.154116 ##
#     8.           "GrayLevelNonUniformity" 52983.057076
#     9. "GrayLevelNonUniformityNormalized" 46005.805970
#    10.                      "RunVariance" 45342.464907
#    11.                "GrayLevelVariance" 44511.441545
#    12. "RunLengthNonUniformityNormalized" 41866.432806
#    13.                 "ShortRunEmphasis" 38809.163409
#    14.                  "LongRunEmphasis" 38327.323007
#    15.                    "RunPercentage" 33977.379565
#    16.           "RunLengthNonUniformity" 32461.568907
#
#
#
# Winner takes all: true
# Out-of-bag evaluation: accuracy:0.858367 logloss:0.429127
# Number of trees: 300
# Total number of nodes: 75340
#
# Number of nodes by tree:
# Count: 300 Average: 251.133 StdDev: 12.8388
# Min: 211 Max: 287 Ignored: 0
# ----------------------------------------------
# [ 211, 214)  1   0.33%   0.33%
# [ 214, 218)  2   0.67%   1.00%
# [ 218, 222)  2   0.67%   1.67%
# [ 222, 226)  3   1.00%   2.67% #
# [ 226, 230)  8   2.67%   5.33% ##
# [ 230, 234) 13   4.33%   9.67% ###
# [ 234, 237)  8   2.67%  12.33% ##
# [ 237, 241) 21   7.00%  19.33% #####
# [ 241, 245) 25   8.33%  27.67% ######
# [ 245, 249) 34  11.33%  39.00% ########
# [ 249, 253) 42  14.00%  53.00% ##########
# [ 253, 257) 37  12.33%  65.33% #########
# [ 257, 261) 30  10.00%  75.33% #######
# [ 261, 264) 23   7.67%  83.00% #####
# [ 264, 268) 25   8.33%  91.33% ######
# [ 268, 272) 18   6.00%  97.33% ####
# [ 272, 276)  2   0.67%  98.00%
# [ 276, 280)  1   0.33%  98.33%
# [ 280, 284)  4   1.33%  99.67% #
# [ 284, 287]  1   0.33% 100.00%
#
# Depth by leafs:
# Count: 37820 Average: 9.30169 StdDev: 2.74422
# Min: 1 Max: 15 Ignored: 0
# ----------------------------------------------
# [  1,  2)    1   0.00%   0.00%
# [  2,  3)   81   0.21%   0.22%
# [  3,  4)  419   1.11%   1.32% #
# [  4,  5)  912   2.41%   3.74% ##
# [  5,  6) 1835   4.85%   8.59% ###
# [  6,  7) 2824   7.47%  16.05% #####
# [  7,  8) 3929  10.39%  26.44% #######
# [  8,  9) 4925  13.02%  39.47% #########
# [  9, 10) 5253  13.89%  53.36% ##########
# [ 10, 11) 5074  13.42%  66.77% ##########
# [ 11, 12) 4163  11.01%  77.78% ########
# [ 12, 13) 3310   8.75%  86.53% ######
# [ 13, 14) 2330   6.16%  92.69% ####
# [ 14, 15) 1580   4.18%  96.87% ###
# [ 15, 15] 1184   3.13% 100.00% ##
#
# Number of training obs by leaf:
# Count: 37820 Average: 60.4204 StdDev: 191.665
# Min: 5 Max: 2550 Ignored: 0
# ----------------------------------------------
# [    5,  132) 34411  90.99%  90.99% ##########
# [  132,  259)  1363   3.60%  94.59%
# [  259,  386)   533   1.41%  96.00%
# [  386,  514)   274   0.72%  96.72%
# [  514,  641)   285   0.75%  97.48%
# [  641,  768)   225   0.59%  98.07%
# [  768,  896)   165   0.44%  98.51%
# [  896, 1023)   187   0.49%  99.00%
# [ 1023, 1150)    82   0.22%  99.22%
# [ 1150, 1278)    45   0.12%  99.34%
# [ 1278, 1405)    49   0.13%  99.47%
# [ 1405, 1532)    51   0.13%  99.60%
# [ 1532, 1659)    50   0.13%  99.74%
# [ 1659, 1787)    27   0.07%  99.81%
# [ 1787, 1914)    31   0.08%  99.89%
# [ 1914, 2041)    21   0.06%  99.94%
# [ 2041, 2169)     9   0.02%  99.97%
# [ 2169, 2296)     7   0.02%  99.99%
# [ 2296, 2423)     4   0.01% 100.00%
# [ 2423, 2550]     1   0.00% 100.00%
#
# Attribute in nodes:
# 	3487 : LongRunHighGrayLevelEmphasis [NUMERICAL]
# 	3229 : RunEntropy [NUMERICAL]
# 	2675 : GrayLevelNonUniformity [NUMERICAL]
# 	2668 : GrayLevelVariance [NUMERICAL]
# 	2621 : HighGrayLevelRunEmphasis [NUMERICAL]
# 	2515 : GrayLevelNonUniformityNormalized [NUMERICAL]
# 	2513 : ShortRunHighGrayLevelEmphasis [NUMERICAL]
# 	2414 : ShortRunLowGrayLevelEmphasis [NUMERICAL]
# 	2414 : LongRunLowGrayLevelEmphasis [NUMERICAL]
# 	2355 : LowGrayLevelRunEmphasis [NUMERICAL]
# 	2075 : RunVariance [NUMERICAL]
# 	1818 : RunLengthNonUniformityNormalized [NUMERICAL]
# 	1777 : LongRunEmphasis [NUMERICAL]
# 	1756 : ShortRunEmphasis [NUMERICAL]
# 	1631 : RunLengthNonUniformity [NUMERICAL]
# 	1572 : RunPercentage [NUMERICAL]
#
# Attribute in nodes with depth <= 0:
# 	101 : LongRunHighGrayLevelEmphasis [NUMERICAL]
# 	55 : ShortRunHighGrayLevelEmphasis [NUMERICAL]
# 	52 : HighGrayLevelRunEmphasis [NUMERICAL]
# 	41 : ShortRunLowGrayLevelEmphasis [NUMERICAL]
# 	26 : LowGrayLevelRunEmphasis [NUMERICAL]
# 	14 : LongRunLowGrayLevelEmphasis [NUMERICAL]
# 	4 : GrayLevelNonUniformityNormalized [NUMERICAL]
# 	3 : RunEntropy [NUMERICAL]
# 	3 : GrayLevelNonUniformity [NUMERICAL]
# 	1 : RunVariance [NUMERICAL]
#
# Attribute in nodes with depth <= 1:
# 	288 : LongRunHighGrayLevelEmphasis [NUMERICAL]
# 	170 : HighGrayLevelRunEmphasis [NUMERICAL]
# 	130 : ShortRunHighGrayLevelEmphasis [NUMERICAL]
# 	93 : ShortRunLowGrayLevelEmphasis [NUMERICAL]
# 	77 : LowGrayLevelRunEmphasis [NUMERICAL]
# 	59 : LongRunLowGrayLevelEmphasis [NUMERICAL]
# 	15 : LongRunEmphasis [NUMERICAL]
# 	15 : GrayLevelNonUniformity [NUMERICAL]
# 	11 : RunVariance [NUMERICAL]
# 	11 : RunEntropy [NUMERICAL]
# 	10 : RunPercentage [NUMERICAL]
# 	7 : RunLengthNonUniformityNormalized [NUMERICAL]
# 	7 : GrayLevelNonUniformityNormalized [NUMERICAL]
# 	4 : ShortRunEmphasis [NUMERICAL]
# 	2 : RunLengthNonUniformity [NUMERICAL]
#
# Attribute in nodes with depth <= 2:
# 	462 : LongRunHighGrayLevelEmphasis [NUMERICAL]
# 	275 : HighGrayLevelRunEmphasis [NUMERICAL]
# 	210 : ShortRunHighGrayLevelEmphasis [NUMERICAL]
# 	157 : LongRunLowGrayLevelEmphasis [NUMERICAL]
# 	156 : LowGrayLevelRunEmphasis [NUMERICAL]
# 	150 : ShortRunLowGrayLevelEmphasis [NUMERICAL]
# 	83 : RunPercentage [NUMERICAL]
# 	82 : RunVariance [NUMERICAL]
# 	77 : LongRunEmphasis [NUMERICAL]
# 	69 : RunLengthNonUniformityNormalized [NUMERICAL]
# 	65 : ShortRunEmphasis [NUMERICAL]
# 	61 : RunLengthNonUniformity [NUMERICAL]
# 	52 : GrayLevelNonUniformity [NUMERICAL]
# 	47 : RunEntropy [NUMERICAL]
# 	35 : GrayLevelVariance [NUMERICAL]
# 	35 : GrayLevelNonUniformityNormalized [NUMERICAL]
#
# Attribute in nodes with depth <= 3:
# 	680 : LongRunHighGrayLevelEmphasis [NUMERICAL]
# 	458 : HighGrayLevelRunEmphasis [NUMERICAL]
# 	361 : ShortRunHighGrayLevelEmphasis [NUMERICAL]
# 	285 : LongRunLowGrayLevelEmphasis [NUMERICAL]
# 	248 : LowGrayLevelRunEmphasis [NUMERICAL]
# 	246 : ShortRunLowGrayLevelEmphasis [NUMERICAL]
# 	187 : RunEntropy [NUMERICAL]
# 	183 : RunVariance [NUMERICAL]
# 	175 : GrayLevelNonUniformity [NUMERICAL]
# 	166 : RunPercentage [NUMERICAL]
# 	166 : LongRunEmphasis [NUMERICAL]
# 	140 : RunLengthNonUniformityNormalized [NUMERICAL]
# 	138 : RunLengthNonUniformity [NUMERICAL]
# 	137 : GrayLevelVariance [NUMERICAL]
# 	134 : GrayLevelNonUniformityNormalized [NUMERICAL]
# 	127 : ShortRunEmphasis [NUMERICAL]
#
# Attribute in nodes with depth <= 5:
# 	1300 : LongRunHighGrayLevelEmphasis [NUMERICAL]
# 	855 : HighGrayLevelRunEmphasis [NUMERICAL]
# 	847 : RunEntropy [NUMERICAL]
# 	766 : ShortRunHighGrayLevelEmphasis [NUMERICAL]
# 	702 : LongRunLowGrayLevelEmphasis [NUMERICAL]
# 	657 : ShortRunLowGrayLevelEmphasis [NUMERICAL]
# 	642 : GrayLevelNonUniformity [NUMERICAL]
# 	624 : LowGrayLevelRunEmphasis [NUMERICAL]
# 	566 : GrayLevelVariance [NUMERICAL]
# 	562 : RunVariance [NUMERICAL]
# 	552 : GrayLevelNonUniformityNormalized [NUMERICAL]
# 	454 : LongRunEmphasis [NUMERICAL]
# 	411 : RunLengthNonUniformity [NUMERICAL]
# 	408 : RunPercentage [NUMERICAL]
# 	402 : ShortRunEmphasis [NUMERICAL]
# 	402 : RunLengthNonUniformityNormalized [NUMERICAL]
#
# Condition type in nodes:
# 	37520 : HigherCondition
# Condition type in nodes with depth <= 0:
# 	300 : HigherCondition
# Condition type in nodes with depth <= 1:
# 	899 : HigherCondition
# Condition type in nodes with depth <= 2:
# 	2016 : HigherCondition
# Condition type in nodes with depth <= 3:
# 	3831 : HigherCondition
# Condition type in nodes with depth <= 5:
# 	10150 : HigherCondition
# Node format: NOT_SET
#
# Training OOB:
# 	trees: 1, Out-of-bag evaluation: accuracy:0.819467 logloss:6.50706
# 	trees: 11, Out-of-bag evaluation: accuracy:0.835274 logloss:2.62255
# 	trees: 21, Out-of-bag evaluation: accuracy:0.844789 logloss:1.66501
# 	trees: 32, Out-of-bag evaluation: accuracy:0.848941 logloss:1.29733
# 	trees: 42, Out-of-bag evaluation: accuracy:0.859776 logloss:1.1127
# 	trees: 52, Out-of-bag evaluation: accuracy:0.857417 logloss:0.97298
# 	trees: 62, Out-of-bag evaluation: accuracy:0.852736 logloss:0.906806
# 	trees: 72, Out-of-bag evaluation: accuracy:0.854636 logloss:0.7998
# 	trees: 82, Out-of-bag evaluation: accuracy:0.856186 logloss:0.800816
# 	trees: 92, Out-of-bag evaluation: accuracy:0.854776 logloss:0.767451
# 	trees: 102, Out-of-bag evaluation: accuracy:0.857978 logloss:0.732667
# 	trees: 112, Out-of-bag evaluation: accuracy:0.857978 logloss:0.729735
# 	trees: 122, Out-of-bag evaluation: accuracy:0.856747 logloss:0.729208
# 	trees: 132, Out-of-bag evaluation: accuracy:0.857168 logloss:0.694031
# 	trees: 142, Out-of-bag evaluation: accuracy:0.857098 logloss:0.69405
# 	trees: 152, Out-of-bag evaluation: accuracy:0.856148 logloss:0.593322
# 	trees: 162, Out-of-bag evaluation: accuracy:0.857308 logloss:0.592487
# 	trees: 172, Out-of-bag evaluation: accuracy:0.859069 logloss:0.561982
# 	trees: 182, Out-of-bag evaluation: accuracy:0.860019 logloss:0.496635
# 	trees: 192, Out-of-bag evaluation: accuracy:0.861109 logloss:0.49547
# 	trees: 202, Out-of-bag evaluation: accuracy:0.859949 logloss:0.496957
# 	trees: 212, Out-of-bag evaluation: accuracy:0.859878 logloss:0.497504
# 	trees: 222, Out-of-bag evaluation: accuracy:0.858788 logloss:0.498372
# 	trees: 232, Out-of-bag evaluation: accuracy:0.858648 logloss:0.497925
# 	trees: 242, Out-of-bag evaluation: accuracy:0.860829 logloss:0.465221
# 	trees: 252, Out-of-bag evaluation: accuracy:0.858858 logloss:0.463802
# 	trees: 262, Out-of-bag evaluation: accuracy:0.858648 logloss:0.431758
# 	trees: 272, Out-of-bag evaluation: accuracy:0.858648 logloss:0.43155
# 	trees: 282, Out-of-bag evaluation: accuracy:0.857557 logloss:0.431556
# 	trees: 292, Out-of-bag evaluation: accuracy:0.858577 logloss:0.429784
# 	trees: 300, Out-of-bag evaluation: accuracy:0.858367 logloss:0.429127

# %%
# Model features
model.make_inspector().features()
# Out:
# ["GrayLevelNonUniformity" (1; #0),
#  "GrayLevelNonUniformityNormalized" (1; #1),
#  "GrayLevelVariance" (1; #2),
#  "HighGrayLevelRunEmphasis" (1; #3),
#  "LongRunEmphasis" (1; #4),
#  "LongRunHighGrayLevelEmphasis" (1; #5),
#  "LongRunLowGrayLevelEmphasis" (1; #6),
#  "LowGrayLevelRunEmphasis" (1; #7),
#  "RunEntropy" (1; #8),
#  "RunLengthNonUniformity" (1; #9),
#  "RunLengthNonUniformityNormalized" (1; #10),
#  "RunPercentage" (1; #11),
#  "RunVariance" (1; #12),
#  "ShortRunEmphasis" (1; #13),
#  "ShortRunHighGrayLevelEmphasis" (1; #14),
#  "ShortRunLowGrayLevelEmphasis" (1; #15)]

# %%
# Feature importance
model.make_inspector().variable_importances()
# Out:
# {'INV_MEAN_MIN_DEPTH': [("LongRunHighGrayLevelEmphasis" (1; #5),
#    0.2829676615934569),
#   ("HighGrayLevelRunEmphasis" (1; #3), 0.17456987394717488),
#   ("ShortRunHighGrayLevelEmphasis" (1; #14), 0.16501746654037597),
#   ("ShortRunLowGrayLevelEmphasis" (1; #15), 0.13972526601399346),
#   ("LowGrayLevelRunEmphasis" (1; #7), 0.1332339100648728),
#   ("LongRunLowGrayLevelEmphasis" (1; #6), 0.13282763860067684),
#   ("RunEntropy" (1; #8), 0.12583296294872232),
#   ("RunVariance" (1; #12), 0.12039904079702389),
#   ("GrayLevelNonUniformity" (1; #0), 0.11929710807079236),
#   ("RunLengthNonUniformityNormalized" (1; #10), 0.1192275954278292),
#   ("ShortRunEmphasis" (1; #13), 0.11783566259206224),
#   ("LongRunEmphasis" (1; #4), 0.11755373492458997),
#   ("RunPercentage" (1; #11), 0.11507926074041624),
#   ("GrayLevelNonUniformityNormalized" (1; #1), 0.11431438393953129),
#   ("GrayLevelVariance" (1; #2), 0.11363885926518331),
#   ("RunLengthNonUniformity" (1; #9), 0.11263673332891443)],
#  'SUM_SCORE': [("LongRunHighGrayLevelEmphasis" (1; #5), 383062.6163165065),
#   ("HighGrayLevelRunEmphasis" (1; #3), 188001.39208576598),
#   ("ShortRunHighGrayLevelEmphasis" (1; #14), 184536.64143973248),
#   ("ShortRunLowGrayLevelEmphasis" (1; #15), 122724.64560414848),
#   ("LowGrayLevelRunEmphasis" (1; #7), 94002.81553817834),
#   ("LongRunLowGrayLevelEmphasis" (1; #6), 79221.57185498194),
#   ("RunEntropy" (1; #8), 77272.15411577576),
#   ("GrayLevelNonUniformity" (1; #0), 52983.057076225836),
#   ("GrayLevelNonUniformityNormalized" (1; #1), 46005.80596956607),
#   ("RunVariance" (1; #12), 45342.464906789384),
#   ("GrayLevelVariance" (1; #2), 44511.441544997855),
#   ("RunLengthNonUniformityNormalized" (1; #10), 41866.432806472825),
#   ("ShortRunEmphasis" (1; #13), 38809.163409071356),
#   ("LongRunEmphasis" (1; #4), 38327.323007341016),
#   ("RunPercentage" (1; #11), 33977.37956481077),
#   ("RunLengthNonUniformity" (1; #9), 32461.56890703733)],
#  'NUM_AS_ROOT': [("LongRunHighGrayLevelEmphasis" (1; #5), 101.0),
#   ("ShortRunHighGrayLevelEmphasis" (1; #14), 55.0),
#   ("HighGrayLevelRunEmphasis" (1; #3), 52.0),
#   ("ShortRunLowGrayLevelEmphasis" (1; #15), 41.0),
#   ("LowGrayLevelRunEmphasis" (1; #7), 26.0),
#   ("LongRunLowGrayLevelEmphasis" (1; #6), 14.0),
#   ("GrayLevelNonUniformityNormalized" (1; #1), 4.0),
#   ("GrayLevelNonUniformity" (1; #0), 3.0),
#   ("RunEntropy" (1; #8), 3.0),
#   ("RunVariance" (1; #12), 1.0)],
#  'NUM_NODES': [("LongRunHighGrayLevelEmphasis" (1; #5), 3487.0),
#   ("RunEntropy" (1; #8), 3229.0),
#   ("GrayLevelNonUniformity" (1; #0), 2675.0),
#   ("GrayLevelVariance" (1; #2), 2668.0),
#   ("HighGrayLevelRunEmphasis" (1; #3), 2621.0),
#   ("GrayLevelNonUniformityNormalized" (1; #1), 2515.0),
#   ("ShortRunHighGrayLevelEmphasis" (1; #14), 2513.0),
#   ("LongRunLowGrayLevelEmphasis" (1; #6), 2414.0),
#   ("ShortRunLowGrayLevelEmphasis" (1; #15), 2414.0),
#   ("LowGrayLevelRunEmphasis" (1; #7), 2355.0),
#   ("RunVariance" (1; #12), 2075.0),
#   ("RunLengthNonUniformityNormalized" (1; #10), 1818.0),
#   ("LongRunEmphasis" (1; #4), 1777.0),
#   ("ShortRunEmphasis" (1; #13), 1756.0),
#   ("RunLengthNonUniformity" (1; #9), 1631.0),
#   ("RunPercentage" (1; #11), 1572.0)]}

# %%
# Model self evaluation
model.make_inspector().evaluation()
# Out:
# Evaluation(num_examples=7617, accuracy=0.8583670039275226, loss=0.4291267858556159, rmse=None, ndcg=None, aucs=None, auuc=None, qini=None)

# %%
logs = model.make_inspector().training_logs()

plt.figure(figsize=(12, 4))
plt.subplot(1, 2, 1)
plt.plot([log.num_trees for log in logs], [log.evaluation.accuracy for log in logs])
plt.xlabel("Number of trees")
plt.ylabel("Accuracy (out-of-bag)")
plt.subplot(1, 2, 2)
plt.plot([log.num_trees for log in logs], [log.evaluation.loss for log in logs])
plt.xlabel("Number of trees")
plt.ylabel("Logloss (out-of-bag)")
plt.show()

# %% [markdown]
# Calculate the score of our hold-out validation dataset

# %%
predictions = model.predict(val_ds)
y_true      = validation_data["label"]

from sklearn.metrics import roc_auc_score
ROC_AUC = roc_auc_score(y_true, predictions)
print("The ROC AUC score is %.5f" % ROC_AUC )
# Out:
# 1/2 [==============>...............] - ETA: 0s
# 2/2 [==============================] - 0s 3ms/step
# The ROC AUC score is 0.99846

# %%
# Compute binary classification metrics with sklearn
import numpy as np
from sklearn.metrics import (
    accuracy_score,
    precision_score,
    recall_score,
    f1_score,
    roc_auc_score,
    average_precision_score,
    confusion_matrix,
    classification_report,
    matthews_corrcoef,
    log_loss,
    brier_score_loss,
)

# Get predictions (probabilities or class labels)
preds = model.predict(test_ds)
# If model outputs probabilities, convert to labels by threshold 0.5
if preds.ndim == 2:
    # For TFDF classification, preds may be class probabilities with shape (N, 2)
    if preds.shape[1] == 2:
        pos_probs = preds[:, 1]
    else:
        # If single-probability column (positive class)
        pos_probs = preds[:, -1]
    y_pred = (pos_probs >= 0.5).astype(int)
else:
    # Already class labels
    y_pred = preds.astype(int)
    pos_probs = None

# Ground truth labels (must be 0/1 integers)
y_true = test_data["label"].astype(int).to_numpy()

# Core metrics
metrics = {}
metrics["accuracy"] = accuracy_score(y_true, y_pred)
metrics["precision"] = precision_score(y_true, y_pred, zero_division=0)
metrics["recall"] = recall_score(y_true, y_pred, zero_division=0)
metrics["f1"] = f1_score(y_true, y_pred, zero_division=0)
metrics["mcc"] = matthews_corrcoef(y_true, y_pred)

# Probabilistic metrics (only if we have probabilities)
if pos_probs is not None:
    metrics["roc_auc"] = roc_auc_score(y_true, pos_probs)
    metrics["pr_auc"] = average_precision_score(y_true, pos_probs)
    metrics["log_loss"] = log_loss(y_true, pos_probs, labels=[0,1])
    metrics["brier_score"] = brier_score_loss(y_true, pos_probs)

# Confusion matrix and detailed report
cm = confusion_matrix(y_true, y_pred, labels=[0,1])
report = classification_report(y_true, y_pred, digits=4)

print("Sklearn binary metrics:")
for k, v in metrics.items():
    print(f"{k}: {v:.4f}")
print("\nConfusion matrix:\n", cm)
print("\nClassification report:\n", report)
# Out:
# 1/3 [=========>....................] - ETA: 0s
# 3/3 [==============================] - 0s 10ms/step
# Sklearn binary metrics:
# accuracy: 0.9676
# precision: 0.9005
# recall: 0.7577
# f1: 0.8230
# mcc: 0.8089
# roc_auc: 0.9647
# pr_auc: 0.8728
# log_loss: 0.1214
# brier_score: 0.0275
#
# Confusion matrix:
#  [[2037   19]
#  [  55  172]]
#
# Classification report:
#                precision    recall  f1-score   support
#
#            0     0.9737    0.9908    0.9822      2056
#            1     0.9005    0.7577    0.8230       227
#
#     accuracy                         0.9676      2283
#    macro avg     0.9371    0.8742    0.9026      2283
# weighted avg     0.9664    0.9676    0.9663      2283
