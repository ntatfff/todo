# %%
# Import packages and modules
import numpy  as np
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow_decision_forests as tfdf

from sklearn.model_selection import train_test_split
# Out:
# 2026-09-12 10:48:16.442409: I tensorflow/core/util/port.cc:113] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2026-09-12 10:48:16.797408: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2026-09-12 10:48:22.337723: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
# Check the version of TensorFlow Decision Forests
print("Found TensorFlow Decision Forests v" + tfdf.__version__)
# Out:
# Found TensorFlow Decision Forests v1.9.1

# %%
datasetPath = "dataset/10p/all/kernel3/"

# %%
# Parameters
datasetPath = "dataset/mask5/10p/ngtdm/kernel5/"

# %%
# train/validation/test = 70/10/20
train_data = pd.read_csv(f"{datasetPath}dataset.train.csv")
validation_data = pd.read_csv(f"{datasetPath}dataset.validation.csv")
test_data = pd.read_csv(f"{datasetPath}dataset.test.csv")

# %%
from sklearn.utils.class_weight import compute_class_weight

# tinh class weight tren tap train
classes = np.array([0, 1])
weights = compute_class_weight(class_weight="balanced", classes=classes, y=train_data["label"])
class_weight = {0: weights[0], 1: weights[1]}

# gan sample_weight cho tung dong
train_data["sample_weight"] = train_data["label"].map(class_weight)
validation_data["sample_weight"] = validation_data["label"].map(class_weight)
test_data["sample_weight"] = test_data["label"].map(class_weight)

# Convert the dataset into a TensorFlow dataset.
train_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    train_data, label="label", weight="sample_weight"
)         
val_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    validation_data, label="label", weight="sample_weight"
)
test_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    test_data, label="label", weight="sample_weight"
)
# Out:
# 2026-09-12 10:48:35.571426: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:984] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2026-09-12 10:48:35.573140: W tensorflow/core/common_runtime/gpu/gpu_device.cc:2251] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...

# %%
import keras

# %%
# %%time

# Train a Random Forest model.
model = tfdf.keras.RandomForestModel()

# Add evaluation metrics
model.compile(
    metrics=["accuracy"]
)
model.fit(x=train_ds)

# # Train a Gradient Boosted Trees model.
# model = tfdf.keras.GradientBoostedTreesModel(num_trees=1500)
# model.fit(train_ds)
# Out:
# Use /tmp/tmpstr9kmt2 as temporary training directory
# Reading training dataset...
# Training dataset read in 0:00:02.573462. Found 7617 examples.
# Training model...
# Model trained in 0:00:00.500853
# Compiling model...
# [INFO 26-09-12 10:48:38.6690 UTC kernel.cc:1233] Loading model from path /tmp/tmpstr9kmt2/model/ with prefix 1d02e45e41b440b8
# [INFO 26-09-12 10:48:38.7785 UTC decision_forest.cc:734] Model loaded with 300 root(s), 86084 node(s), and 5 input feature(s).
# [INFO 26-09-12 10:48:38.7785 UTC abstract_model.cc:1362] Engine "RandomForestOptPred" built
# [INFO 26-09-12 10:48:38.7785 UTC kernel.cc:1061] Use fast generic engine
# Model compiled.
# CPU times: user 9.1 s, sys: 129 ms, total: 9.23 s
# Wall time: 6.25 s

# %%
# Evaluate the model
evaluate = model.evaluate(val_ds, return_dict=True)
print()

for name, value in evaluate.items():
    print(f"{name}: {value:.4f}")
# Out:
# WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 1/2 [==============>...............] - ETA: 3s - loss: 0.0000e+00 - accuracy: 0.9810
# 2/2 [==============================] - 3s 8ms/step - loss: 0.0000e+00 - accuracy: 0.9814
# loss: 0.0000
# accuracy: 0.9814

# %%
# Model Summary
model.summary()
# Out:
# Model: "random_forest_model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
# =================================================================
# Total params: 1 (1.00 Byte)
# Trainable params: 0 (0.00 Byte)
# Non-trainable params: 1 (1.00 Byte)
# _________________________________________________________________
# Type: "RANDOM_FOREST"
# Task: CLASSIFICATION
# Label: "__LABEL"
#
# Input Features (5):
# 	Busyness
# 	Coarseness
# 	Complexity
# 	Contrast
# 	Strength
#
# Trained with weights
#
# Variable Importance: INV_MEAN_MIN_DEPTH:
#     1.   "Busyness"  0.810696 ################
#     2. "Coarseness"  0.261596 ##
#     3. "Complexity"  0.197340
#     4.   "Strength"  0.167251
#     5.   "Contrast"  0.163058
#
# Variable Importance: NUM_AS_ROOT:
#     1.   "Busyness" 245.000000 ################
#     2. "Coarseness" 55.000000
#
# Variable Importance: NUM_NODES:
#     1.   "Busyness" 10766.000000 ################
#     2.   "Strength" 9039.000000 ########
#     3. "Complexity" 8300.000000 ####
#     4.   "Contrast" 7570.000000 #
#     5. "Coarseness" 7217.000000
#
# Variable Importance: SUM_SCORE:
#     1.   "Busyness" 796400.027607 ################
#     2. "Coarseness" 208216.078397 #
#     3. "Complexity" 191159.350018 #
#     4.   "Strength" 152150.639176
#     5.   "Contrast" 136806.251350
#
#
#
# Winner takes all: true
# Out-of-bag evaluation: accuracy:0.846441 logloss:0.685928
# Number of trees: 300
# Total number of nodes: 86084
#
# Number of nodes by tree:
# Count: 300 Average: 286.947 StdDev: 15.1938
# Min: 241 Max: 331 Ignored: 0
# ----------------------------------------------
# [ 241, 245)  1   0.33%   0.33%
# [ 245, 250)  2   0.67%   1.00%
# [ 250, 254)  5   1.67%   2.67% #
# [ 254, 259)  2   0.67%   3.33%
# [ 259, 263)  5   1.67%   5.00% #
# [ 263, 268) 18   6.00%  11.00% ####
# [ 268, 272) 12   4.00%  15.00% ###
# [ 272, 277) 26   8.67%  23.67% ######
# [ 277, 281) 24   8.00%  31.67% ######
# [ 281, 286) 38  12.67%  44.33% #########
# [ 286, 291) 41  13.67%  58.00% ##########
# [ 291, 295) 34  11.33%  69.33% ########
# [ 295, 300) 32  10.67%  80.00% ########
# [ 300, 304) 23   7.67%  87.67% ######
# [ 304, 309)  9   3.00%  90.67% ##
# [ 309, 313) 13   4.33%  95.00% ###
# [ 313, 318) 11   3.67%  98.67% ###
# [ 318, 322)  0   0.00%  98.67%
# [ 322, 327)  3   1.00%  99.67% #
# [ 327, 331]  1   0.33% 100.00%
#
# Depth by leafs:
# Count: 43192 Average: 9.00468 StdDev: 2.52186
# Min: 2 Max: 15 Ignored: 0
# ----------------------------------------------
# [  2,  3)   19   0.04%   0.04%
# [  3,  4)  169   0.39%   0.44%
# [  4,  5)  840   1.94%   2.38% #
# [  5,  6) 2254   5.22%   7.60% ###
# [  6,  7) 3950   9.15%  16.74% ######
# [  7,  8) 5449  12.62%  29.36% ########
# [  8,  9) 6495  15.04%  44.40% ##########
# [  9, 10) 6456  14.95%  59.34% ##########
# [ 10, 11) 5717  13.24%  72.58% #########
# [ 11, 12) 4536  10.50%  83.08% #######
# [ 12, 13) 3118   7.22%  90.30% #####
# [ 13, 14) 2102   4.87%  95.17% ###
# [ 14, 15) 1265   2.93%  98.10% ##
# [ 15, 15]  822   1.90% 100.00% #
#
# Number of training obs by leaf:
# Count: 43192 Average: 52.9056 StdDev: 191.102
# Min: 5 Max: 2862 Ignored: 0
# ----------------------------------------------
# [    5,  147) 40392  93.52%  93.52% ##########
# [  147,  290)  1085   2.51%  96.03%
# [  290,  433)   491   1.14%  97.17%
# [  433,  576)   337   0.78%  97.95%
# [  576,  719)   205   0.47%  98.42%
# [  719,  862)   134   0.31%  98.73%
# [  862, 1005)    72   0.17%  98.90%
# [ 1005, 1148)    46   0.11%  99.00%
# [ 1148, 1291)    78   0.18%  99.19%
# [ 1291, 1434)    71   0.16%  99.35%
# [ 1434, 1576)    74   0.17%  99.52%
# [ 1576, 1719)    59   0.14%  99.66%
# [ 1719, 1862)    46   0.11%  99.76%
# [ 1862, 2005)    42   0.10%  99.86%
# [ 2005, 2148)    24   0.06%  99.92%
# [ 2148, 2291)    14   0.03%  99.95%
# [ 2291, 2434)    10   0.02%  99.97%
# [ 2434, 2577)     7   0.02%  99.99%
# [ 2577, 2720)     2   0.00%  99.99%
# [ 2720, 2862]     3   0.01% 100.00%
#
# Attribute in nodes:
# 	10766 : Busyness [NUMERICAL]
# 	9039 : Strength [NUMERICAL]
# 	8300 : Complexity [NUMERICAL]
# 	7570 : Contrast [NUMERICAL]
# 	7217 : Coarseness [NUMERICAL]
#
# Attribute in nodes with depth <= 0:
# 	245 : Busyness [NUMERICAL]
# 	55 : Coarseness [NUMERICAL]
#
# Attribute in nodes with depth <= 1:
# 	548 : Busyness [NUMERICAL]
# 	269 : Coarseness [NUMERICAL]
# 	63 : Contrast [NUMERICAL]
# 	18 : Strength [NUMERICAL]
# 	2 : Complexity [NUMERICAL]
#
# Attribute in nodes with depth <= 2:
# 	1052 : Busyness [NUMERICAL]
# 	363 : Coarseness [NUMERICAL]
# 	358 : Complexity [NUMERICAL]
# 	187 : Contrast [NUMERICAL]
# 	121 : Strength [NUMERICAL]
#
# Attribute in nodes with depth <= 3:
# 	1778 : Busyness [NUMERICAL]
# 	870 : Complexity [NUMERICAL]
# 	645 : Strength [NUMERICAL]
# 	596 : Coarseness [NUMERICAL]
# 	385 : Contrast [NUMERICAL]
#
# Attribute in nodes with depth <= 5:
# 	4027 : Busyness [NUMERICAL]
# 	2589 : Strength [NUMERICAL]
# 	2502 : Complexity [NUMERICAL]
# 	1810 : Coarseness [NUMERICAL]
# 	1730 : Contrast [NUMERICAL]
#
# Condition type in nodes:
# 	42892 : HigherCondition
# Condition type in nodes with depth <= 0:
# 	300 : HigherCondition
# Condition type in nodes with depth <= 1:
# 	900 : HigherCondition
# Condition type in nodes with depth <= 2:
# 	2081 : HigherCondition
# Condition type in nodes with depth <= 3:
# 	4274 : HigherCondition
# Condition type in nodes with depth <= 5:
# 	12658 : HigherCondition
# Node format: NOT_SET
#
# Training OOB:
# 	trees: 1, Out-of-bag evaluation: accuracy:0.822159 logloss:6.41004
# 	trees: 12, Out-of-bag evaluation: accuracy:0.822298 logloss:3.48855
# 	trees: 22, Out-of-bag evaluation: accuracy:0.82734 logloss:2.09566
# 	trees: 32, Out-of-bag evaluation: accuracy:0.837965 logloss:1.76544
# 	trees: 43, Out-of-bag evaluation: accuracy:0.837155 logloss:1.72472
# 	trees: 53, Out-of-bag evaluation: accuracy:0.837296 logloss:1.51691
# 	trees: 63, Out-of-bag evaluation: accuracy:0.837155 logloss:1.41195
# 	trees: 73, Out-of-bag evaluation: accuracy:0.834725 logloss:1.30992
# 	trees: 83, Out-of-bag evaluation: accuracy:0.837787 logloss:1.21046
# 	trees: 93, Out-of-bag evaluation: accuracy:0.840778 logloss:1.11138
# 	trees: 103, Out-of-bag evaluation: accuracy:0.84419 logloss:1.07987
# 	trees: 113, Out-of-bag evaluation: accuracy:0.841199 logloss:1.08019
# 	trees: 123, Out-of-bag evaluation: accuracy:0.841199 logloss:1.04866
# 	trees: 133, Out-of-bag evaluation: accuracy:0.840988 logloss:0.883323
# 	trees: 143, Out-of-bag evaluation: accuracy:0.840918 logloss:0.817862
# 	trees: 153, Out-of-bag evaluation: accuracy:0.841058 logloss:0.786607
# 	trees: 163, Out-of-bag evaluation: accuracy:0.842219 logloss:0.786911
# 	trees: 173, Out-of-bag evaluation: accuracy:0.84514 logloss:0.786026
# 	trees: 183, Out-of-bag evaluation: accuracy:0.841938 logloss:0.785513
# 	trees: 193, Out-of-bag evaluation: accuracy:0.843099 logloss:0.783348
# 	trees: 204, Out-of-bag evaluation: accuracy:0.84338 logloss:0.783598
# 	trees: 214, Out-of-bag evaluation: accuracy:0.84352 logloss:0.752337
# 	trees: 224, Out-of-bag evaluation: accuracy:0.847461 logloss:0.752419
# 	trees: 234, Out-of-bag evaluation: accuracy:0.846581 logloss:0.750934
# 	trees: 244, Out-of-bag evaluation: accuracy:0.8444 logloss:0.752028
# 	trees: 254, Out-of-bag evaluation: accuracy:0.847531 logloss:0.751253
# 	trees: 264, Out-of-bag evaluation: accuracy:0.845421 logloss:0.75189
# 	trees: 274, Out-of-bag evaluation: accuracy:0.84454 logloss:0.75178
# 	trees: 284, Out-of-bag evaluation: accuracy:0.845701 logloss:0.720367
# 	trees: 294, Out-of-bag evaluation: accuracy:0.846301 logloss:0.686119
# 	trees: 300, Out-of-bag evaluation: accuracy:0.846441 logloss:0.685928

# %%
# Model features
model.make_inspector().features()
# Out:
# ["Busyness" (1; #0),
#  "Coarseness" (1; #1),
#  "Complexity" (1; #2),
#  "Contrast" (1; #3),
#  "Strength" (1; #4)]

# %%
# Feature importance
model.make_inspector().variable_importances()
# Out:
# {'INV_MEAN_MIN_DEPTH': [("Busyness" (1; #0), 0.810695787060457),
#   ("Coarseness" (1; #1), 0.2615956836163374),
#   ("Complexity" (1; #2), 0.1973397120172973),
#   ("Strength" (1; #4), 0.16725058575401733),
#   ("Contrast" (1; #3), 0.16305788932176332)],
#  'SUM_SCORE': [("Busyness" (1; #0), 796400.0276069111),
#   ("Coarseness" (1; #1), 208216.0783968594),
#   ("Complexity" (1; #2), 191159.35001827462),
#   ("Strength" (1; #4), 152150.639175978),
#   ("Contrast" (1; #3), 136806.25135040566)],
#  'NUM_AS_ROOT': [("Busyness" (1; #0), 245.0), ("Coarseness" (1; #1), 55.0)],
#  'NUM_NODES': [("Busyness" (1; #0), 10766.0),
#   ("Strength" (1; #4), 9039.0),
#   ("Complexity" (1; #2), 8300.0),
#   ("Contrast" (1; #3), 7570.0),
#   ("Coarseness" (1; #1), 7217.0)]}

# %%
# Model self evaluation
model.make_inspector().evaluation()
# Out:
# Evaluation(num_examples=7617, accuracy=0.8464409567258431, loss=0.6859275401494336, rmse=None, ndcg=None, aucs=None, auuc=None, qini=None)

# %%
logs = model.make_inspector().training_logs()

plt.figure(figsize=(12, 4))
plt.subplot(1, 2, 1)
plt.plot([log.num_trees for log in logs], [log.evaluation.accuracy for log in logs])
plt.xlabel("Number of trees")
plt.ylabel("Accuracy (out-of-bag)")
plt.subplot(1, 2, 2)
plt.plot([log.num_trees for log in logs], [log.evaluation.loss for log in logs])
plt.xlabel("Number of trees")
plt.ylabel("Logloss (out-of-bag)")
plt.show()

# %% [markdown]
# Calculate the score of our hold-out validation dataset

# %%
predictions = model.predict(val_ds)
y_true      = validation_data["label"]

from sklearn.metrics import roc_auc_score
ROC_AUC = roc_auc_score(y_true, predictions)
print("The ROC AUC score is %.5f" % ROC_AUC )
# Out:
# 1/2 [==============>...............] - ETA: 0s
# 2/2 [==============================] - 0s 3ms/step
# The ROC AUC score is 0.99073

# %%
# Compute binary classification metrics with sklearn
import numpy as np
from sklearn.metrics import (
    accuracy_score,
    precision_score,
    recall_score,
    f1_score,
    roc_auc_score,
    average_precision_score,
    confusion_matrix,
    classification_report,
    matthews_corrcoef,
    log_loss,
    brier_score_loss,
)

# Get predictions (probabilities or class labels)
preds = model.predict(test_ds)
# If model outputs probabilities, convert to labels by threshold 0.5
if preds.ndim == 2:
    # For TFDF classification, preds may be class probabilities with shape (N, 2)
    if preds.shape[1] == 2:
        pos_probs = preds[:, 1]
    else:
        # If single-probability column (positive class)
        pos_probs = preds[:, -1]
    y_pred = (pos_probs >= 0.5).astype(int)
else:
    # Already class labels
    y_pred = preds.astype(int)
    pos_probs = None

# Ground truth labels (must be 0/1 integers)
y_true = test_data["label"].astype(int).to_numpy()

# Core metrics
metrics = {}
metrics["accuracy"] = accuracy_score(y_true, y_pred)
metrics["precision"] = precision_score(y_true, y_pred, zero_division=0)
metrics["recall"] = recall_score(y_true, y_pred, zero_division=0)
metrics["f1"] = f1_score(y_true, y_pred, zero_division=0)
metrics["mcc"] = matthews_corrcoef(y_true, y_pred)

# Probabilistic metrics (only if we have probabilities)
if pos_probs is not None:
    metrics["roc_auc"] = roc_auc_score(y_true, pos_probs)
    metrics["pr_auc"] = average_precision_score(y_true, pos_probs)
    metrics["log_loss"] = log_loss(y_true, pos_probs, labels=[0,1])
    metrics["brier_score"] = brier_score_loss(y_true, pos_probs)

# Confusion matrix and detailed report
cm = confusion_matrix(y_true, y_pred, labels=[0,1])
report = classification_report(y_true, y_pred, digits=4)

print("Sklearn binary metrics:")
for k, v in metrics.items():
    print(f"{k}: {v:.4f}")
print("\nConfusion matrix:\n", cm)
print("\nClassification report:\n", report)
# Out:
# 1/3 [=========>....................] - ETA: 0s
# 3/3 [==============================] - 0s 10ms/step
# Sklearn binary metrics:
# accuracy: 0.9562
# precision: 0.8547
# recall: 0.6740
# f1: 0.7537
# mcc: 0.7362
# roc_auc: 0.9588
# pr_auc: 0.8335
# log_loss: 0.1362
# brier_score: 0.0348
#
# Confusion matrix:
#  [[2030   26]
#  [  74  153]]
#
# Classification report:
#                precision    recall  f1-score   support
#
#            0     0.9648    0.9874    0.9760      2056
#            1     0.8547    0.6740    0.7537       227
#
#     accuracy                         0.9562      2283
#    macro avg     0.9098    0.8307    0.8648      2283
# weighted avg     0.9539    0.9562    0.9539      2283
