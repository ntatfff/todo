# %%
# Import packages and modules
import numpy  as np
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow_decision_forests as tfdf

from sklearn.model_selection import train_test_split
# Out:
# 2026-09-12 10:39:45.534424: I tensorflow/core/util/port.cc:113] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2026-09-12 10:39:45.892167: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2026-09-12 10:39:50.421234: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
# Check the version of TensorFlow Decision Forests
print("Found TensorFlow Decision Forests v" + tfdf.__version__)
# Out:
# Found TensorFlow Decision Forests v1.9.1

# %%
datasetPath = "dataset/10p/all/kernel3/"

# %%
# Parameters
datasetPath = "dataset/mask5/10p/ngtdm/kernel3/"

# %%
# train/validation/test = 70/10/20
train_data = pd.read_csv(f"{datasetPath}dataset.train.csv")
validation_data = pd.read_csv(f"{datasetPath}dataset.validation.csv")
test_data = pd.read_csv(f"{datasetPath}dataset.test.csv")

# %%
from sklearn.utils.class_weight import compute_class_weight

# tinh class weight tren tap train
classes = np.array([0, 1])
weights = compute_class_weight(class_weight="balanced", classes=classes, y=train_data["label"])
class_weight = {0: weights[0], 1: weights[1]}

# gan sample_weight cho tung dong
train_data["sample_weight"] = train_data["label"].map(class_weight)
validation_data["sample_weight"] = validation_data["label"].map(class_weight)
test_data["sample_weight"] = test_data["label"].map(class_weight)

# Convert the dataset into a TensorFlow dataset.
train_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    train_data, label="label", weight="sample_weight"
)         
val_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    validation_data, label="label", weight="sample_weight"
)
test_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    test_data, label="label", weight="sample_weight"
)
# Out:
# 2026-09-12 10:40:02.834894: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:984] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2026-09-12 10:40:02.836319: W tensorflow/core/common_runtime/gpu/gpu_device.cc:2251] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...

# %%
import keras

# %%
# %%time

# Train a Random Forest model.
model = tfdf.keras.RandomForestModel()

# Add evaluation metrics
model.compile(
    metrics=["accuracy"]
)
model.fit(x=train_ds)

# # Train a Gradient Boosted Trees model.
# model = tfdf.keras.GradientBoostedTreesModel(num_trees=1500)
# model.fit(train_ds)
# Out:
# Use /tmp/tmpoaoi41pm as temporary training directory
# Reading training dataset...
# Training dataset read in 0:00:02.487629. Found 7617 examples.
# Training model...
# Model trained in 0:00:00.542585
# Compiling model...
# [INFO 26-09-12 10:40:05.8623 UTC kernel.cc:1233] Loading model from path /tmp/tmpoaoi41pm/model/ with prefix baa27f5eb56c4203
# [INFO 26-09-12 10:40:05.9888 UTC decision_forest.cc:734] Model loaded with 300 root(s), 98836 node(s), and 5 input feature(s).
# [INFO 26-09-12 10:40:05.9889 UTC abstract_model.cc:1362] Engine "RandomForestOptPred" built
# [INFO 26-09-12 10:40:05.9889 UTC kernel.cc:1061] Use fast generic engine
# Model compiled.
# CPU times: user 9.03 s, sys: 131 ms, total: 9.16 s
# Wall time: 6.89 s

# %%
# Evaluate the model
evaluate = model.evaluate(val_ds, return_dict=True)
print()

for name, value in evaluate.items():
    print(f"{name}: {value:.4f}")
# Out:
# WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 1/2 [==============>...............] - ETA: 2s - loss: 0.0000e+00 - accuracy: 0.9810
# 2/2 [==============================] - 3s 8ms/step - loss: 0.0000e+00 - accuracy: 0.9805
# loss: 0.0000
# accuracy: 0.9805

# %%
# Model Summary
model.summary()
# Out:
# Model: "random_forest_model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
# =================================================================
# Total params: 1 (1.00 Byte)
# Trainable params: 0 (0.00 Byte)
# Non-trainable params: 1 (1.00 Byte)
# _________________________________________________________________
# Type: "RANDOM_FOREST"
# Task: CLASSIFICATION
# Label: "__LABEL"
#
# Input Features (5):
# 	Busyness
# 	Coarseness
# 	Complexity
# 	Contrast
# 	Strength
#
# Trained with weights
#
# Variable Importance: INV_MEAN_MIN_DEPTH:
#     1.   "Busyness"  0.808649 ################
#     2. "Coarseness"  0.208738 #
#     3.   "Contrast"  0.187771
#     4. "Complexity"  0.177799
#     5.   "Strength"  0.158211
#
# Variable Importance: NUM_AS_ROOT:
#     1.   "Busyness" 245.000000 ################
#     2. "Coarseness" 55.000000
#
# Variable Importance: NUM_NODES:
#     1.   "Busyness" 12319.000000 ################
#     2.   "Strength" 10308.000000 #######
#     3. "Complexity" 9131.000000 #
#     4.   "Contrast" 8815.000000
#     5. "Coarseness" 8695.000000
#
# Variable Importance: SUM_SCORE:
#     1.   "Busyness" 736050.231451 ################
#     2. "Complexity" 190977.494948
#     3. "Coarseness" 187723.198270
#     4.   "Contrast" 180519.333641
#     5.   "Strength" 171681.984566
#
#
#
# Winner takes all: true
# Out-of-bag evaluation: accuracy:0.798093 logloss:1.00105
# Number of trees: 300
# Total number of nodes: 98836
#
# Number of nodes by tree:
# Count: 300 Average: 329.453 StdDev: 17.3692
# Min: 289 Max: 391 Ignored: 0
# ----------------------------------------------
# [ 289, 294)  5   1.67%   1.67% #
# [ 294, 299)  2   0.67%   2.33% #
# [ 299, 304) 11   3.67%   6.00% ###
# [ 304, 309) 16   5.33%  11.33% ####
# [ 309, 314) 29   9.67%  21.00% ########
# [ 314, 319) 20   6.67%  27.67% #####
# [ 319, 325) 36  12.00%  39.67% #########
# [ 325, 330) 38  12.67%  52.33% ##########
# [ 330, 335) 25   8.33%  60.67% #######
# [ 335, 340) 31  10.33%  71.00% ########
# [ 340, 345) 27   9.00%  80.00% #######
# [ 345, 350) 19   6.33%  86.33% #####
# [ 350, 355) 16   5.33%  91.67% ####
# [ 355, 361) 12   4.00%  95.67% ###
# [ 361, 366)  9   3.00%  98.67% ##
# [ 366, 371)  3   1.00%  99.67% #
# [ 371, 376)  0   0.00%  99.67%
# [ 376, 381)  0   0.00%  99.67%
# [ 381, 386)  0   0.00%  99.67%
# [ 386, 391]  1   0.33% 100.00%
#
# Depth by leafs:
# Count: 49568 Average: 9.25799 StdDev: 2.50894
# Min: 2 Max: 15 Ignored: 0
# ----------------------------------------------
# [  2,  3)   16   0.03%   0.03%
# [  3,  4)  222   0.45%   0.48%
# [  4,  5)  693   1.40%   1.88% #
# [  5,  6) 2126   4.29%   6.17% ###
# [  6,  7) 3850   7.77%  13.93% #####
# [  7,  8) 5736  11.57%  25.51% ########
# [  8,  9) 7055  14.23%  39.74% #########
# [  9, 10) 7569  15.27%  55.01% ##########
# [ 10, 11) 7135  14.39%  69.40% #########
# [ 11, 12) 5672  11.44%  80.85% #######
# [ 12, 13) 4044   8.16%  89.01% #####
# [ 13, 14) 2749   5.55%  94.55% ####
# [ 14, 15) 1535   3.10%  97.65% ##
# [ 15, 15] 1166   2.35% 100.00% ##
#
# Number of training obs by leaf:
# Count: 49568 Average: 46.1003 StdDev: 144.739
# Min: 5 Max: 2795 Ignored: 0
# ----------------------------------------------
# [    5,  144) 46297  93.40%  93.40% ##########
# [  144,  284)  1521   3.07%  96.47%
# [  284,  423)   495   1.00%  97.47%
# [  423,  563)   300   0.61%  98.07%
# [  563,  702)   304   0.61%  98.69%
# [  702,  842)   207   0.42%  99.10%
# [  842,  981)   141   0.28%  99.39%
# [  981, 1121)    78   0.16%  99.55%
# [ 1121, 1260)    77   0.16%  99.70%
# [ 1260, 1400)    56   0.11%  99.81%
# [ 1400, 1540)    38   0.08%  99.89%
# [ 1540, 1679)    24   0.05%  99.94%
# [ 1679, 1819)    13   0.03%  99.97%
# [ 1819, 1958)     9   0.02%  99.98%
# [ 1958, 2098)     1   0.00%  99.99%
# [ 2098, 2237)     4   0.01%  99.99%
# [ 2237, 2377)     1   0.00% 100.00%
# [ 2377, 2516)     0   0.00% 100.00%
# [ 2516, 2656)     1   0.00% 100.00%
# [ 2656, 2795]     1   0.00% 100.00%
#
# Attribute in nodes:
# 	12319 : Busyness [NUMERICAL]
# 	10308 : Strength [NUMERICAL]
# 	9131 : Complexity [NUMERICAL]
# 	8815 : Contrast [NUMERICAL]
# 	8695 : Coarseness [NUMERICAL]
#
# Attribute in nodes with depth <= 0:
# 	245 : Busyness [NUMERICAL]
# 	55 : Coarseness [NUMERICAL]
#
# Attribute in nodes with depth <= 1:
# 	568 : Busyness [NUMERICAL]
# 	177 : Coarseness [NUMERICAL]
# 	121 : Contrast [NUMERICAL]
# 	23 : Complexity [NUMERICAL]
# 	11 : Strength [NUMERICAL]
#
# Attribute in nodes with depth <= 2:
# 	1088 : Busyness [NUMERICAL]
# 	280 : Coarseness [NUMERICAL]
# 	275 : Contrast [NUMERICAL]
# 	232 : Complexity [NUMERICAL]
# 	209 : Strength [NUMERICAL]
#
# Attribute in nodes with depth <= 3:
# 	1846 : Busyness [NUMERICAL]
# 	745 : Strength [NUMERICAL]
# 	650 : Complexity [NUMERICAL]
# 	512 : Contrast [NUMERICAL]
# 	477 : Coarseness [NUMERICAL]
#
# Attribute in nodes with depth <= 5:
# 	4229 : Busyness [NUMERICAL]
# 	2696 : Strength [NUMERICAL]
# 	2222 : Complexity [NUMERICAL]
# 	1961 : Contrast [NUMERICAL]
# 	1793 : Coarseness [NUMERICAL]
#
# Condition type in nodes:
# 	49268 : HigherCondition
# Condition type in nodes with depth <= 0:
# 	300 : HigherCondition
# Condition type in nodes with depth <= 1:
# 	900 : HigherCondition
# Condition type in nodes with depth <= 2:
# 	2084 : HigherCondition
# Condition type in nodes with depth <= 3:
# 	4230 : HigherCondition
# Condition type in nodes with depth <= 5:
# 	12901 : HigherCondition
# Node format: NOT_SET
#
# Training OOB:
# 	trees: 1, Out-of-bag evaluation: accuracy:0.76765 logloss:8.37472
# 	trees: 11, Out-of-bag evaluation: accuracy:0.777535 logloss:4.07663
# 	trees: 21, Out-of-bag evaluation: accuracy:0.796128 logloss:2.84888
# 	trees: 31, Out-of-bag evaluation: accuracy:0.804075 logloss:2.2167
# 	trees: 41, Out-of-bag evaluation: accuracy:0.799961 logloss:2.07921
# 	trees: 51, Out-of-bag evaluation: accuracy:0.801014 logloss:1.80718
# 	trees: 61, Out-of-bag evaluation: accuracy:0.807806 logloss:1.63611
# 	trees: 71, Out-of-bag evaluation: accuracy:0.810197 logloss:1.63532
# 	trees: 81, Out-of-bag evaluation: accuracy:0.804426 logloss:1.59894
# 	trees: 91, Out-of-bag evaluation: accuracy:0.803055 logloss:1.46626
# 	trees: 101, Out-of-bag evaluation: accuracy:0.799783 logloss:1.33324
# 	trees: 111, Out-of-bag evaluation: accuracy:0.798833 logloss:1.29926
# 	trees: 121, Out-of-bag evaluation: accuracy:0.798833 logloss:1.23106
# 	trees: 131, Out-of-bag evaluation: accuracy:0.799923 logloss:1.23189
# 	trees: 141, Out-of-bag evaluation: accuracy:0.800803 logloss:1.23116
# 	trees: 151, Out-of-bag evaluation: accuracy:0.803125 logloss:1.16342
# 	trees: 161, Out-of-bag evaluation: accuracy:0.801154 logloss:1.13115
# 	trees: 171, Out-of-bag evaluation: accuracy:0.802914 logloss:1.09803
# 	trees: 181, Out-of-bag evaluation: accuracy:0.804075 logloss:1.09851
# 	trees: 191, Out-of-bag evaluation: accuracy:0.801084 logloss:1.09881
# 	trees: 201, Out-of-bag evaluation: accuracy:0.798973 logloss:1.0998
# 	trees: 211, Out-of-bag evaluation: accuracy:0.798163 logloss:1.06609
# 	trees: 221, Out-of-bag evaluation: accuracy:0.799043 logloss:1.06503
# 	trees: 231, Out-of-bag evaluation: accuracy:0.800063 logloss:1.00045
# 	trees: 241, Out-of-bag evaluation: accuracy:0.797952 logloss:0.999331
# 	trees: 251, Out-of-bag evaluation: accuracy:0.799253 logloss:1.00045
# 	trees: 261, Out-of-bag evaluation: accuracy:0.797213 logloss:1.0017
# 	trees: 271, Out-of-bag evaluation: accuracy:0.799993 logloss:1.00144
# 	trees: 281, Out-of-bag evaluation: accuracy:0.797952 logloss:1.00238
# 	trees: 291, Out-of-bag evaluation: accuracy:0.797002 logloss:1.00103
# 	trees: 300, Out-of-bag evaluation: accuracy:0.798093 logloss:1.00105

# %%
# Model features
model.make_inspector().features()
# Out:
# ["Busyness" (1; #0),
#  "Coarseness" (1; #1),
#  "Complexity" (1; #2),
#  "Contrast" (1; #3),
#  "Strength" (1; #4)]

# %%
# Feature importance
model.make_inspector().variable_importances()
# Out:
# {'INV_MEAN_MIN_DEPTH': [("Busyness" (1; #0), 0.8086489334733276),
#   ("Coarseness" (1; #1), 0.20873825804332308),
#   ("Contrast" (1; #3), 0.1877712164682249),
#   ("Complexity" (1; #2), 0.17779891763411604),
#   ("Strength" (1; #4), 0.15821058390144804)],
#  'SUM_SCORE': [("Busyness" (1; #0), 736050.2314511611),
#   ("Complexity" (1; #2), 190977.49494804387),
#   ("Coarseness" (1; #1), 187723.19827027764),
#   ("Contrast" (1; #3), 180519.33364072355),
#   ("Strength" (1; #4), 171681.98456570008)],
#  'NUM_AS_ROOT': [("Busyness" (1; #0), 245.0), ("Coarseness" (1; #1), 55.0)],
#  'NUM_NODES': [("Busyness" (1; #0), 12319.0),
#   ("Strength" (1; #4), 10308.0),
#   ("Complexity" (1; #2), 9131.0),
#   ("Contrast" (1; #3), 8815.0),
#   ("Coarseness" (1; #1), 8695.0)]}

# %%
# Model self evaluation
model.make_inspector().evaluation()
# Out:
# Evaluation(num_examples=7617, accuracy=0.7980927668450968, loss=1.001049196864549, rmse=None, ndcg=None, aucs=None, auuc=None, qini=None)

# %%
logs = model.make_inspector().training_logs()

plt.figure(figsize=(12, 4))
plt.subplot(1, 2, 1)
plt.plot([log.num_trees for log in logs], [log.evaluation.accuracy for log in logs])
plt.xlabel("Number of trees")
plt.ylabel("Accuracy (out-of-bag)")
plt.subplot(1, 2, 2)
plt.plot([log.num_trees for log in logs], [log.evaluation.loss for log in logs])
plt.xlabel("Number of trees")
plt.ylabel("Logloss (out-of-bag)")
plt.show()

# %% [markdown]
# Calculate the score of our hold-out validation dataset

# %%
predictions = model.predict(val_ds)
y_true      = validation_data["label"]

from sklearn.metrics import roc_auc_score
ROC_AUC = roc_auc_score(y_true, predictions)
print("The ROC AUC score is %.5f" % ROC_AUC )
# Out:
# 1/2 [==============>...............] - ETA: 0s
# 2/2 [==============================] - 0s 4ms/step
# The ROC AUC score is 0.97167

# %%
# Compute binary classification metrics with sklearn
import numpy as np
from sklearn.metrics import (
    accuracy_score,
    precision_score,
    recall_score,
    f1_score,
    roc_auc_score,
    average_precision_score,
    confusion_matrix,
    classification_report,
    matthews_corrcoef,
    log_loss,
    brier_score_loss,
)

# Get predictions (probabilities or class labels)
preds = model.predict(test_ds)
# If model outputs probabilities, convert to labels by threshold 0.5
if preds.ndim == 2:
    # For TFDF classification, preds may be class probabilities with shape (N, 2)
    if preds.shape[1] == 2:
        pos_probs = preds[:, 1]
    else:
        # If single-probability column (positive class)
        pos_probs = preds[:, -1]
    y_pred = (pos_probs >= 0.5).astype(int)
else:
    # Already class labels
    y_pred = preds.astype(int)
    pos_probs = None

# Ground truth labels (must be 0/1 integers)
y_true = test_data["label"].astype(int).to_numpy()

# Core metrics
metrics = {}
metrics["accuracy"] = accuracy_score(y_true, y_pred)
metrics["precision"] = precision_score(y_true, y_pred, zero_division=0)
metrics["recall"] = recall_score(y_true, y_pred, zero_division=0)
metrics["f1"] = f1_score(y_true, y_pred, zero_division=0)
metrics["mcc"] = matthews_corrcoef(y_true, y_pred)

# Probabilistic metrics (only if we have probabilities)
if pos_probs is not None:
    metrics["roc_auc"] = roc_auc_score(y_true, pos_probs)
    metrics["pr_auc"] = average_precision_score(y_true, pos_probs)
    metrics["log_loss"] = log_loss(y_true, pos_probs, labels=[0,1])
    metrics["brier_score"] = brier_score_loss(y_true, pos_probs)

# Confusion matrix and detailed report
cm = confusion_matrix(y_true, y_pred, labels=[0,1])
report = classification_report(y_true, y_pred, digits=4)

print("Sklearn binary metrics:")
for k, v in metrics.items():
    print(f"{k}: {v:.4f}")
print("\nConfusion matrix:\n", cm)
print("\nClassification report:\n", report)
# Out:
# 1/3 [=========>....................] - ETA: 0s
# 3/3 [==============================] - 0s 10ms/step
# Sklearn binary metrics:
# accuracy: 0.9488
# precision: 0.8716
# recall: 0.5683
# f1: 0.6880
# mcc: 0.6794
# roc_auc: 0.9362
# pr_auc: 0.7993
# log_loss: 0.1763
# brier_score: 0.0384
#
# Confusion matrix:
#  [[2037   19]
#  [  98  129]]
#
# Classification report:
#                precision    recall  f1-score   support
#
#            0     0.9541    0.9908    0.9721      2056
#            1     0.8716    0.5683    0.6880       227
#
#     accuracy                         0.9488      2283
#    macro avg     0.9129    0.7795    0.8300      2283
# weighted avg     0.9459    0.9488    0.9438      2283
