# %%
# Import packages and modules
import numpy  as np
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow_decision_forests as tfdf

from sklearn.model_selection import train_test_split
# Out:
# 2026-09-12 10:38:34.099373: I tensorflow/core/util/port.cc:113] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2026-09-12 10:38:34.476344: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2026-09-12 10:38:39.842491: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
# Check the version of TensorFlow Decision Forests
print("Found TensorFlow Decision Forests v" + tfdf.__version__)
# Out:
# Found TensorFlow Decision Forests v1.9.1

# %%
datasetPath = "dataset/10p/all/kernel3/"

# %%
# Parameters
datasetPath = "dataset/mask5/10p/glrlm/kernel3/"

# %%
# train/validation/test = 70/10/20
train_data = pd.read_csv(f"{datasetPath}dataset.train.csv")
validation_data = pd.read_csv(f"{datasetPath}dataset.validation.csv")
test_data = pd.read_csv(f"{datasetPath}dataset.test.csv")

# %%
from sklearn.utils.class_weight import compute_class_weight

# tinh class weight tren tap train
classes = np.array([0, 1])
weights = compute_class_weight(class_weight="balanced", classes=classes, y=train_data["label"])
class_weight = {0: weights[0], 1: weights[1]}

# gan sample_weight cho tung dong
train_data["sample_weight"] = train_data["label"].map(class_weight)
validation_data["sample_weight"] = validation_data["label"].map(class_weight)
test_data["sample_weight"] = test_data["label"].map(class_weight)

# Convert the dataset into a TensorFlow dataset.
train_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    train_data, label="label", weight="sample_weight"
)         
val_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    validation_data, label="label", weight="sample_weight"
)
test_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    test_data, label="label", weight="sample_weight"
)
# Out:
# 2026-09-12 10:38:52.203530: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:984] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2026-09-12 10:38:52.204764: W tensorflow/core/common_runtime/gpu/gpu_device.cc:2251] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...

# %%
import keras

# %%
# %%time

# Train a Random Forest model.
model = tfdf.keras.RandomForestModel()

# Add evaluation metrics
model.compile(
    metrics=["accuracy"]
)
model.fit(x=train_ds)

# # Train a Gradient Boosted Trees model.
# model = tfdf.keras.GradientBoostedTreesModel(num_trees=1500)
# model.fit(train_ds)
# Out:
# Use /tmp/tmp_1vwm2dd as temporary training directory
# Reading training dataset...
# Training dataset read in 0:00:02.649266. Found 7617 examples.
# Training model...
# Model trained in 0:00:00.520152
# Compiling model...
# [INFO 26-09-12 10:38:55.4230 UTC kernel.cc:1233] Loading model from path /tmp/tmp_1vwm2dd/model/ with prefix 8709a9f10bbc4282
# [INFO 26-09-12 10:38:55.5243 UTC decision_forest.cc:734] Model loaded with 300 root(s), 79450 node(s), and 16 input feature(s).
# [INFO 26-09-12 10:38:55.5243 UTC abstract_model.cc:1362] Engine "RandomForestOptPred" built
# [INFO 26-09-12 10:38:55.5243 UTC kernel.cc:1061] Use fast generic engine
# Model compiled.
# CPU times: user 9.38 s, sys: 135 ms, total: 9.51 s
# Wall time: 6.23 s

# %%
# Evaluate the model
evaluate = model.evaluate(val_ds, return_dict=True)
print()

for name, value in evaluate.items():
    print(f"{name}: {value:.4f}")
# Out:
# WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 1/2 [==============>...............] - ETA: 3s - loss: 0.0000e+00 - accuracy: 0.9910
# 2/2 [==============================] - 3s 9ms/step - loss: 0.0000e+00 - accuracy: 0.9907
# loss: 0.0000
# accuracy: 0.9907

# %%
# Model Summary
model.summary()
# Out:
# Model: "random_forest_model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
# =================================================================
# Total params: 1 (1.00 Byte)
# Trainable params: 0 (0.00 Byte)
# Non-trainable params: 1 (1.00 Byte)
# _________________________________________________________________
# Type: "RANDOM_FOREST"
# Task: CLASSIFICATION
# Label: "__LABEL"
#
# Input Features (16):
# 	GrayLevelNonUniformity
# 	GrayLevelNonUniformityNormalized
# 	GrayLevelVariance
# 	HighGrayLevelRunEmphasis
# 	LongRunEmphasis
# 	LongRunHighGrayLevelEmphasis
# 	LongRunLowGrayLevelEmphasis
# 	LowGrayLevelRunEmphasis
# 	RunEntropy
# 	RunLengthNonUniformity
# 	RunLengthNonUniformityNormalized
# 	RunPercentage
# 	RunVariance
# 	ShortRunEmphasis
# 	ShortRunHighGrayLevelEmphasis
# 	ShortRunLowGrayLevelEmphasis
#
# Trained with weights
#
# Variable Importance: INV_MEAN_MIN_DEPTH:
#     1.     "LongRunHighGrayLevelEmphasis"  0.259392 ################
#     2.         "HighGrayLevelRunEmphasis"  0.171824 ######
#     3.    "ShortRunHighGrayLevelEmphasis"  0.154849 ####
#     4.     "ShortRunLowGrayLevelEmphasis"  0.147288 ###
#     5.          "LowGrayLevelRunEmphasis"  0.143064 ###
#     6.      "LongRunLowGrayLevelEmphasis"  0.133242 ##
#     7.                       "RunEntropy"  0.124132 #
#     8.                      "RunVariance"  0.122014 #
#     9. "GrayLevelNonUniformityNormalized"  0.118694
#    10.           "GrayLevelNonUniformity"  0.117768
#    11.                 "ShortRunEmphasis"  0.116702
#    12.                  "LongRunEmphasis"  0.115972
#    13.                "GrayLevelVariance"  0.115744
#    14. "RunLengthNonUniformityNormalized"  0.113920
#    15.           "RunLengthNonUniformity"  0.112834
#    16.                    "RunPercentage"  0.111324
#
# Variable Importance: NUM_AS_ROOT:
#     1.     "LongRunHighGrayLevelEmphasis" 101.000000 ################
#     2.         "HighGrayLevelRunEmphasis" 56.000000 ########
#     3.    "ShortRunHighGrayLevelEmphasis" 49.000000 #######
#     4.     "ShortRunLowGrayLevelEmphasis" 42.000000 ######
#     5.          "LowGrayLevelRunEmphasis" 27.000000 ####
#     6.      "LongRunLowGrayLevelEmphasis" 14.000000 ##
#     7. "GrayLevelNonUniformityNormalized"  5.000000
#     8.                       "RunEntropy"  3.000000
#     9.           "GrayLevelNonUniformity"  2.000000
#    10.                      "RunVariance"  1.000000
#
# Variable Importance: NUM_NODES:
#     1.     "LongRunHighGrayLevelEmphasis" 3368.000000 ################
#     2.                       "RunEntropy" 3073.000000 #############
#     3.                "GrayLevelVariance" 2850.000000 ##########
#     4.           "GrayLevelNonUniformity" 2774.000000 #########
#     5.         "HighGrayLevelRunEmphasis" 2694.000000 #########
#     6. "GrayLevelNonUniformityNormalized" 2586.000000 ########
#     7.    "ShortRunHighGrayLevelEmphasis" 2566.000000 #######
#     8.      "LongRunLowGrayLevelEmphasis" 2545.000000 #######
#     9.     "ShortRunLowGrayLevelEmphasis" 2540.000000 #######
#    10.                      "RunVariance" 2473.000000 ######
#    11.          "LowGrayLevelRunEmphasis" 2459.000000 ######
#    12.                  "LongRunEmphasis" 2134.000000 ###
#    13.                 "ShortRunEmphasis" 2003.000000 ##
#    14. "RunLengthNonUniformityNormalized" 1908.000000 #
#    15.                    "RunPercentage" 1811.000000
#    16.           "RunLengthNonUniformity" 1791.000000
#
# Variable Importance: SUM_SCORE:
#     1.     "LongRunHighGrayLevelEmphasis" 345985.811154 ################
#     2.         "HighGrayLevelRunEmphasis" 189341.224801 #######
#     3.    "ShortRunHighGrayLevelEmphasis" 166262.258945 ######
#     4.     "ShortRunLowGrayLevelEmphasis" 137041.849717 #####
#     5.          "LowGrayLevelRunEmphasis" 109959.634947 ###
#     6.      "LongRunLowGrayLevelEmphasis" 81818.531285 ##
#     7.                       "RunEntropy" 71227.388205 #
#     8.                      "RunVariance" 53884.835325 #
#     9. "GrayLevelNonUniformityNormalized" 51192.821685
#    10.                "GrayLevelVariance" 50767.598579
#    11.           "GrayLevelNonUniformity" 50507.008826
#    12.                  "LongRunEmphasis" 42071.376991
#    13.                 "ShortRunEmphasis" 38884.754243
#    14. "RunLengthNonUniformityNormalized" 36834.676480
#    15.                    "RunPercentage" 33557.938318
#    16.           "RunLengthNonUniformity" 33347.918891
#
#
#
# Winner takes all: true
# Out-of-bag evaluation: accuracy:0.8375 logloss:0.726161
# Number of trees: 300
# Total number of nodes: 79450
#
# Number of nodes by tree:
# Count: 300 Average: 264.833 StdDev: 15.5087
# Min: 227 Max: 309 Ignored: 0
# ----------------------------------------------
# [ 227, 231)  2   0.67%   0.67% #
# [ 231, 235)  5   1.67%   2.33% #
# [ 235, 239)  6   2.00%   4.33% ##
# [ 239, 243) 10   3.33%   7.67% ###
# [ 243, 247) 19   6.33%  14.00% #####
# [ 247, 251) 11   3.67%  17.67% ###
# [ 251, 256) 28   9.33%  27.00% ########
# [ 256, 260) 33  11.00%  38.00% #########
# [ 260, 264) 27   9.00%  47.00% ########
# [ 264, 268) 35  11.67%  58.67% ##########
# [ 268, 272) 16   5.33%  64.00% #####
# [ 272, 276) 35  11.67%  75.67% ##########
# [ 276, 280) 23   7.67%  83.33% #######
# [ 280, 285) 19   6.33%  89.67% #####
# [ 285, 289)  9   3.00%  92.67% ###
# [ 289, 293) 12   4.00%  96.67% ###
# [ 293, 297)  4   1.33%  98.00% #
# [ 297, 301)  5   1.67%  99.67% #
# [ 301, 305)  0   0.00%  99.67%
# [ 305, 309]  1   0.33% 100.00%
#
# Depth by leafs:
# Count: 39875 Average: 9.34736 StdDev: 2.7175
# Min: 1 Max: 15 Ignored: 0
# ----------------------------------------------
# [  1,  2)    1   0.00%   0.00%
# [  2,  3)   46   0.12%   0.12%
# [  3,  4)  473   1.19%   1.30% #
# [  4,  5)  888   2.23%   3.53% ##
# [  5,  6) 1753   4.40%   7.93% ###
# [  6,  7) 2987   7.49%  15.42% #####
# [  7,  8) 4148  10.40%  25.82% #######
# [  8,  9) 5022  12.59%  38.42% #########
# [  9, 10) 5662  14.20%  52.61% ##########
# [ 10, 11) 5421  13.59%  66.21% ##########
# [ 11, 12) 4592  11.52%  77.73% ########
# [ 12, 13) 3558   8.92%  86.65% ######
# [ 13, 14) 2459   6.17%  92.82% ####
# [ 14, 15) 1555   3.90%  96.71% ###
# [ 15, 15] 1310   3.29% 100.00% ##
#
# Number of training obs by leaf:
# Count: 39875 Average: 57.3066 StdDev: 174.462
# Min: 5 Max: 2092 Ignored: 0
# ----------------------------------------------
# [    5,  109) 35927  90.10%  90.10% ##########
# [  109,  213)  1505   3.77%  93.87%
# [  213,  318)   665   1.67%  95.54%
# [  318,  422)   411   1.03%  96.57%
# [  422,  527)   266   0.67%  97.24%
# [  527,  631)   212   0.53%  97.77%
# [  631,  735)   138   0.35%  98.12%
# [  735,  840)   116   0.29%  98.41%
# [  840,  944)   101   0.25%  98.66%
# [  944, 1049)   149   0.37%  99.03%
# [ 1049, 1153)   128   0.32%  99.36%
# [ 1153, 1257)    62   0.16%  99.51%
# [ 1257, 1362)    54   0.14%  99.65%
# [ 1362, 1466)    39   0.10%  99.74%
# [ 1466, 1571)    41   0.10%  99.85%
# [ 1571, 1675)    26   0.07%  99.91%
# [ 1675, 1779)    17   0.04%  99.95%
# [ 1779, 1884)    10   0.03%  99.98%
# [ 1884, 1988)     5   0.01%  99.99%
# [ 1988, 2092]     3   0.01% 100.00%
#
# Attribute in nodes:
# 	3368 : LongRunHighGrayLevelEmphasis [NUMERICAL]
# 	3073 : RunEntropy [NUMERICAL]
# 	2850 : GrayLevelVariance [NUMERICAL]
# 	2774 : GrayLevelNonUniformity [NUMERICAL]
# 	2694 : HighGrayLevelRunEmphasis [NUMERICAL]
# 	2586 : GrayLevelNonUniformityNormalized [NUMERICAL]
# 	2566 : ShortRunHighGrayLevelEmphasis [NUMERICAL]
# 	2545 : LongRunLowGrayLevelEmphasis [NUMERICAL]
# 	2540 : ShortRunLowGrayLevelEmphasis [NUMERICAL]
# 	2473 : RunVariance [NUMERICAL]
# 	2459 : LowGrayLevelRunEmphasis [NUMERICAL]
# 	2134 : LongRunEmphasis [NUMERICAL]
# 	2003 : ShortRunEmphasis [NUMERICAL]
# 	1908 : RunLengthNonUniformityNormalized [NUMERICAL]
# 	1811 : RunPercentage [NUMERICAL]
# 	1791 : RunLengthNonUniformity [NUMERICAL]
#
# Attribute in nodes with depth <= 0:
# 	101 : LongRunHighGrayLevelEmphasis [NUMERICAL]
# 	56 : HighGrayLevelRunEmphasis [NUMERICAL]
# 	49 : ShortRunHighGrayLevelEmphasis [NUMERICAL]
# 	42 : ShortRunLowGrayLevelEmphasis [NUMERICAL]
# 	27 : LowGrayLevelRunEmphasis [NUMERICAL]
# 	14 : LongRunLowGrayLevelEmphasis [NUMERICAL]
# 	5 : GrayLevelNonUniformityNormalized [NUMERICAL]
# 	3 : RunEntropy [NUMERICAL]
# 	2 : GrayLevelNonUniformity [NUMERICAL]
# 	1 : RunVariance [NUMERICAL]
#
# Attribute in nodes with depth <= 1:
# 	268 : LongRunHighGrayLevelEmphasis [NUMERICAL]
# 	172 : HighGrayLevelRunEmphasis [NUMERICAL]
# 	119 : ShortRunHighGrayLevelEmphasis [NUMERICAL]
# 	112 : LowGrayLevelRunEmphasis [NUMERICAL]
# 	105 : ShortRunLowGrayLevelEmphasis [NUMERICAL]
# 	76 : LongRunLowGrayLevelEmphasis [NUMERICAL]
# 	13 : GrayLevelNonUniformityNormalized [NUMERICAL]
# 	8 : GrayLevelNonUniformity [NUMERICAL]
# 	5 : ShortRunEmphasis [NUMERICAL]
# 	5 : RunVariance [NUMERICAL]
# 	5 : RunEntropy [NUMERICAL]
# 	3 : RunLengthNonUniformityNormalized [NUMERICAL]
# 	3 : LongRunEmphasis [NUMERICAL]
# 	2 : RunPercentage [NUMERICAL]
# 	2 : GrayLevelVariance [NUMERICAL]
# 	1 : RunLengthNonUniformity [NUMERICAL]
#
# Attribute in nodes with depth <= 2:
# 	486 : LongRunHighGrayLevelEmphasis [NUMERICAL]
# 	299 : HighGrayLevelRunEmphasis [NUMERICAL]
# 	203 : ShortRunHighGrayLevelEmphasis [NUMERICAL]
# 	189 : LowGrayLevelRunEmphasis [NUMERICAL]
# 	183 : ShortRunLowGrayLevelEmphasis [NUMERICAL]
# 	135 : LongRunLowGrayLevelEmphasis [NUMERICAL]
# 	81 : GrayLevelNonUniformityNormalized [NUMERICAL]
# 	75 : GrayLevelNonUniformity [NUMERICAL]
# 	65 : RunVariance [NUMERICAL]
# 	59 : RunEntropy [NUMERICAL]
# 	57 : LongRunEmphasis [NUMERICAL]
# 	56 : ShortRunEmphasis [NUMERICAL]
# 	53 : RunLengthNonUniformityNormalized [NUMERICAL]
# 	40 : RunLengthNonUniformity [NUMERICAL]
# 	37 : RunPercentage [NUMERICAL]
# 	33 : GrayLevelVariance [NUMERICAL]
#
# Attribute in nodes with depth <= 3:
# 	680 : LongRunHighGrayLevelEmphasis [NUMERICAL]
# 	439 : HighGrayLevelRunEmphasis [NUMERICAL]
# 	374 : ShortRunHighGrayLevelEmphasis [NUMERICAL]
# 	310 : ShortRunLowGrayLevelEmphasis [NUMERICAL]
# 	309 : LowGrayLevelRunEmphasis [NUMERICAL]
# 	255 : LongRunLowGrayLevelEmphasis [NUMERICAL]
# 	210 : GrayLevelNonUniformityNormalized [NUMERICAL]
# 	202 : GrayLevelNonUniformity [NUMERICAL]
# 	192 : RunEntropy [NUMERICAL]
# 	179 : RunVariance [NUMERICAL]
# 	150 : GrayLevelVariance [NUMERICAL]
# 	137 : LongRunEmphasis [NUMERICAL]
# 	128 : ShortRunEmphasis [NUMERICAL]
# 	121 : RunLengthNonUniformityNormalized [NUMERICAL]
# 	99 : RunLengthNonUniformity [NUMERICAL]
# 	97 : RunPercentage [NUMERICAL]
#
# Attribute in nodes with depth <= 5:
# 	1242 : LongRunHighGrayLevelEmphasis [NUMERICAL]
# 	865 : HighGrayLevelRunEmphasis [NUMERICAL]
# 	814 : ShortRunHighGrayLevelEmphasis [NUMERICAL]
# 	792 : RunEntropy [NUMERICAL]
# 	754 : ShortRunLowGrayLevelEmphasis [NUMERICAL]
# 	721 : LowGrayLevelRunEmphasis [NUMERICAL]
# 	698 : LongRunLowGrayLevelEmphasis [NUMERICAL]
# 	629 : GrayLevelNonUniformityNormalized [NUMERICAL]
# 	604 : GrayLevelNonUniformity [NUMERICAL]
# 	601 : GrayLevelVariance [NUMERICAL]
# 	596 : RunVariance [NUMERICAL]
# 	462 : LongRunEmphasis [NUMERICAL]
# 	449 : ShortRunEmphasis [NUMERICAL]
# 	437 : RunLengthNonUniformityNormalized [NUMERICAL]
# 	394 : RunPercentage [NUMERICAL]
# 	393 : RunLengthNonUniformity [NUMERICAL]
#
# Condition type in nodes:
# 	39575 : HigherCondition
# Condition type in nodes with depth <= 0:
# 	300 : HigherCondition
# Condition type in nodes with depth <= 1:
# 	899 : HigherCondition
# Condition type in nodes with depth <= 2:
# 	2051 : HigherCondition
# Condition type in nodes with depth <= 3:
# 	3882 : HigherCondition
# Condition type in nodes with depth <= 5:
# 	10451 : HigherCondition
# Node format: NOT_SET
#
# Training OOB:
# 	trees: 1, Out-of-bag evaluation: accuracy:0.840517 logloss:5.74834
# 	trees: 11, Out-of-bag evaluation: accuracy:0.8346 logloss:4.08971
# 	trees: 21, Out-of-bag evaluation: accuracy:0.830064 logloss:2.05442
# 	trees: 31, Out-of-bag evaluation: accuracy:0.843871 logloss:1.73697
# 	trees: 41, Out-of-bag evaluation: accuracy:0.83838 logloss:1.50152
# 	trees: 51, Out-of-bag evaluation: accuracy:0.8394 logloss:1.3642
# 	trees: 61, Out-of-bag evaluation: accuracy:0.83912 logloss:1.1959
# 	trees: 71, Out-of-bag evaluation: accuracy:0.837959 logloss:1.195
# 	trees: 81, Out-of-bag evaluation: accuracy:0.835529 logloss:1.16313
# 	trees: 91, Out-of-bag evaluation: accuracy:0.834088 logloss:1.06099
# 	trees: 101, Out-of-bag evaluation: accuracy:0.836128 logloss:1.0273
# 	trees: 111, Out-of-bag evaluation: accuracy:0.835319 logloss:1.02641
# 	trees: 121, Out-of-bag evaluation: accuracy:0.835529 logloss:0.989157
# 	trees: 131, Out-of-bag evaluation: accuracy:0.838731 logloss:0.923306
# 	trees: 141, Out-of-bag evaluation: accuracy:0.83859 logloss:0.891769
# 	trees: 151, Out-of-bag evaluation: accuracy:0.83757 logloss:0.892965
# 	trees: 161, Out-of-bag evaluation: accuracy:0.839751 logloss:0.86089
# 	trees: 171, Out-of-bag evaluation: accuracy:0.841651 logloss:0.861159
# 	trees: 181, Out-of-bag evaluation: accuracy:0.838731 logloss:0.82914
# 	trees: 191, Out-of-bag evaluation: accuracy:0.837359 logloss:0.8268
# 	trees: 201, Out-of-bag evaluation: accuracy:0.83845 logloss:0.825149
# 	trees: 211, Out-of-bag evaluation: accuracy:0.840561 logloss:0.825117
# 	trees: 221, Out-of-bag evaluation: accuracy:0.83852 logloss:0.826245
# 	trees: 231, Out-of-bag evaluation: accuracy:0.838871 logloss:0.826955
# 	trees: 241, Out-of-bag evaluation: accuracy:0.838941 logloss:0.793344
# 	trees: 251, Out-of-bag evaluation: accuracy:0.839891 logloss:0.793253
# 	trees: 261, Out-of-bag evaluation: accuracy:0.839891 logloss:0.792973
# 	trees: 271, Out-of-bag evaluation: accuracy:0.839681 logloss:0.759864
# 	trees: 281, Out-of-bag evaluation: accuracy:0.83859 logloss:0.759018
# 	trees: 291, Out-of-bag evaluation: accuracy:0.839751 logloss:0.758802
# 	trees: 300, Out-of-bag evaluation: accuracy:0.8375 logloss:0.726161

# %%
# Model features
model.make_inspector().features()
# Out:
# ["GrayLevelNonUniformity" (1; #0),
#  "GrayLevelNonUniformityNormalized" (1; #1),
#  "GrayLevelVariance" (1; #2),
#  "HighGrayLevelRunEmphasis" (1; #3),
#  "LongRunEmphasis" (1; #4),
#  "LongRunHighGrayLevelEmphasis" (1; #5),
#  "LongRunLowGrayLevelEmphasis" (1; #6),
#  "LowGrayLevelRunEmphasis" (1; #7),
#  "RunEntropy" (1; #8),
#  "RunLengthNonUniformity" (1; #9),
#  "RunLengthNonUniformityNormalized" (1; #10),
#  "RunPercentage" (1; #11),
#  "RunVariance" (1; #12),
#  "ShortRunEmphasis" (1; #13),
#  "ShortRunHighGrayLevelEmphasis" (1; #14),
#  "ShortRunLowGrayLevelEmphasis" (1; #15)]

# %%
# Feature importance
model.make_inspector().variable_importances()
# Out:
# {'INV_MEAN_MIN_DEPTH': [("LongRunHighGrayLevelEmphasis" (1; #5),
#    0.2593920689420365),
#   ("HighGrayLevelRunEmphasis" (1; #3), 0.1718241027627096),
#   ("ShortRunHighGrayLevelEmphasis" (1; #14), 0.15484855786885157),
#   ("ShortRunLowGrayLevelEmphasis" (1; #15), 0.14728798553526387),
#   ("LowGrayLevelRunEmphasis" (1; #7), 0.1430637755649792),
#   ("LongRunLowGrayLevelEmphasis" (1; #6), 0.13324187634975554),
#   ("RunEntropy" (1; #8), 0.12413213715241417),
#   ("RunVariance" (1; #12), 0.1220140482523976),
#   ("GrayLevelNonUniformityNormalized" (1; #1), 0.11869381736821934),
#   ("GrayLevelNonUniformity" (1; #0), 0.11776791299192836),
#   ("ShortRunEmphasis" (1; #13), 0.11670165096147814),
#   ("LongRunEmphasis" (1; #4), 0.11597196500842075),
#   ("GrayLevelVariance" (1; #2), 0.11574401551359582),
#   ("RunLengthNonUniformityNormalized" (1; #10), 0.1139197999347754),
#   ("RunLengthNonUniformity" (1; #9), 0.11283403576197869),
#   ("RunPercentage" (1; #11), 0.11132357198137971)],
#  'SUM_SCORE': [("LongRunHighGrayLevelEmphasis" (1; #5), 345985.81115427974),
#   ("HighGrayLevelRunEmphasis" (1; #3), 189341.22480084343),
#   ("ShortRunHighGrayLevelEmphasis" (1; #14), 166262.25894503776),
#   ("ShortRunLowGrayLevelEmphasis" (1; #15), 137041.8497171365),
#   ("LowGrayLevelRunEmphasis" (1; #7), 109959.6349470342),
#   ("LongRunLowGrayLevelEmphasis" (1; #6), 81818.531285095),
#   ("RunEntropy" (1; #8), 71227.38820490829),
#   ("RunVariance" (1; #12), 53884.835325418535),
#   ("GrayLevelNonUniformityNormalized" (1; #1), 51192.82168454631),
#   ("GrayLevelVariance" (1; #2), 50767.59857851129),
#   ("GrayLevelNonUniformity" (1; #0), 50507.00882597347),
#   ("LongRunEmphasis" (1; #4), 42071.37699089434),
#   ("ShortRunEmphasis" (1; #13), 38884.75424304072),
#   ("RunLengthNonUniformityNormalized" (1; #10), 36834.676480014765),
#   ("RunPercentage" (1; #11), 33557.93831787088),
#   ("RunLengthNonUniformity" (1; #9), 33347.91889104257)],
#  'NUM_AS_ROOT': [("LongRunHighGrayLevelEmphasis" (1; #5), 101.0),
#   ("HighGrayLevelRunEmphasis" (1; #3), 56.0),
#   ("ShortRunHighGrayLevelEmphasis" (1; #14), 49.0),
#   ("ShortRunLowGrayLevelEmphasis" (1; #15), 42.0),
#   ("LowGrayLevelRunEmphasis" (1; #7), 27.0),
#   ("LongRunLowGrayLevelEmphasis" (1; #6), 14.0),
#   ("GrayLevelNonUniformityNormalized" (1; #1), 5.0),
#   ("RunEntropy" (1; #8), 3.0),
#   ("GrayLevelNonUniformity" (1; #0), 2.0),
#   ("RunVariance" (1; #12), 1.0)],
#  'NUM_NODES': [("LongRunHighGrayLevelEmphasis" (1; #5), 3368.0),
#   ("RunEntropy" (1; #8), 3073.0),
#   ("GrayLevelVariance" (1; #2), 2850.0),
#   ("GrayLevelNonUniformity" (1; #0), 2774.0),
#   ("HighGrayLevelRunEmphasis" (1; #3), 2694.0),
#   ("GrayLevelNonUniformityNormalized" (1; #1), 2586.0),
#   ("ShortRunHighGrayLevelEmphasis" (1; #14), 2566.0),
#   ("LongRunLowGrayLevelEmphasis" (1; #6), 2545.0),
#   ("ShortRunLowGrayLevelEmphasis" (1; #15), 2540.0),
#   ("RunVariance" (1; #12), 2473.0),
#   ("LowGrayLevelRunEmphasis" (1; #7), 2459.0),
#   ("LongRunEmphasis" (1; #4), 2134.0),
#   ("ShortRunEmphasis" (1; #13), 2003.0),
#   ("RunLengthNonUniformityNormalized" (1; #10), 1908.0),
#   ("RunPercentage" (1; #11), 1811.0),
#   ("RunLengthNonUniformity" (1; #9), 1791.0)]}

# %%
# Model self evaluation
model.make_inspector().evaluation()
# Out:
# Evaluation(num_examples=7617, accuracy=0.837499678573231, loss=0.7261608744673153, rmse=None, ndcg=None, aucs=None, auuc=None, qini=None)

# %%
logs = model.make_inspector().training_logs()

plt.figure(figsize=(12, 4))
plt.subplot(1, 2, 1)
plt.plot([log.num_trees for log in logs], [log.evaluation.accuracy for log in logs])
plt.xlabel("Number of trees")
plt.ylabel("Accuracy (out-of-bag)")
plt.subplot(1, 2, 2)
plt.plot([log.num_trees for log in logs], [log.evaluation.loss for log in logs])
plt.xlabel("Number of trees")
plt.ylabel("Logloss (out-of-bag)")
plt.show()

# %% [markdown]
# Calculate the score of our hold-out validation dataset

# %%
predictions = model.predict(val_ds)
y_true      = validation_data["label"]

from sklearn.metrics import roc_auc_score
ROC_AUC = roc_auc_score(y_true, predictions)
print("The ROC AUC score is %.5f" % ROC_AUC )
# Out:
# 1/2 [==============>...............] - ETA: 0s
# 2/2 [==============================] - 0s 4ms/step
# The ROC AUC score is 0.99445

# %%
# Compute binary classification metrics with sklearn
import numpy as np
from sklearn.metrics import (
    accuracy_score,
    precision_score,
    recall_score,
    f1_score,
    roc_auc_score,
    average_precision_score,
    confusion_matrix,
    classification_report,
    matthews_corrcoef,
    log_loss,
    brier_score_loss,
)

# Get predictions (probabilities or class labels)
preds = model.predict(test_ds)
# If model outputs probabilities, convert to labels by threshold 0.5
if preds.ndim == 2:
    # For TFDF classification, preds may be class probabilities with shape (N, 2)
    if preds.shape[1] == 2:
        pos_probs = preds[:, 1]
    else:
        # If single-probability column (positive class)
        pos_probs = preds[:, -1]
    y_pred = (pos_probs >= 0.5).astype(int)
else:
    # Already class labels
    y_pred = preds.astype(int)
    pos_probs = None

# Ground truth labels (must be 0/1 integers)
y_true = test_data["label"].astype(int).to_numpy()

# Core metrics
metrics = {}
metrics["accuracy"] = accuracy_score(y_true, y_pred)
metrics["precision"] = precision_score(y_true, y_pred, zero_division=0)
metrics["recall"] = recall_score(y_true, y_pred, zero_division=0)
metrics["f1"] = f1_score(y_true, y_pred, zero_division=0)
metrics["mcc"] = matthews_corrcoef(y_true, y_pred)

# Probabilistic metrics (only if we have probabilities)
if pos_probs is not None:
    metrics["roc_auc"] = roc_auc_score(y_true, pos_probs)
    metrics["pr_auc"] = average_precision_score(y_true, pos_probs)
    metrics["log_loss"] = log_loss(y_true, pos_probs, labels=[0,1])
    metrics["brier_score"] = brier_score_loss(y_true, pos_probs)

# Confusion matrix and detailed report
cm = confusion_matrix(y_true, y_pred, labels=[0,1])
report = classification_report(y_true, y_pred, digits=4)

print("Sklearn binary metrics:")
for k, v in metrics.items():
    print(f"{k}: {v:.4f}")
print("\nConfusion matrix:\n", cm)
print("\nClassification report:\n", report)
# Out:
# 1/3 [=========>....................] - ETA: 0s
# 3/3 [==============================] - 0s 11ms/step
# Sklearn binary metrics:
# accuracy: 0.9680
# precision: 0.9231
# recall: 0.7401
# f1: 0.8215
# mcc: 0.8101
# roc_auc: 0.9535
# pr_auc: 0.8610
# log_loss: 0.1406
# brier_score: 0.0282
#
# Confusion matrix:
#  [[2042   14]
#  [  59  168]]
#
# Classification report:
#                precision    recall  f1-score   support
#
#            0     0.9719    0.9932    0.9824      2056
#            1     0.9231    0.7401    0.8215       227
#
#     accuracy                         0.9680      2283
#    macro avg     0.9475    0.8666    0.9020      2283
# weighted avg     0.9671    0.9680    0.9664      2283
