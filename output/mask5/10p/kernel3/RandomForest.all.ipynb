# %%
# Import packages and modules
import numpy  as np
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow_decision_forests as tfdf

from sklearn.model_selection import train_test_split
# Out:
# 2026-09-12 10:35:32.707334: I tensorflow/core/util/port.cc:113] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2026-09-12 10:35:36.587842: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2026-09-12 10:35:54.489068: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
# Check the version of TensorFlow Decision Forests
print("Found TensorFlow Decision Forests v" + tfdf.__version__)
# Out:
# Found TensorFlow Decision Forests v1.9.1

# %%
datasetPath = "dataset/10p/all/kernel3/"

# %%
# Parameters
datasetPath = "dataset/mask5/10p/all/kernel3/"

# %%
# train/validation/test = 70/10/20
train_data = pd.read_csv(f"{datasetPath}dataset.train.csv")
validation_data = pd.read_csv(f"{datasetPath}dataset.validation.csv")
test_data = pd.read_csv(f"{datasetPath}dataset.test.csv")

# %%
from sklearn.utils.class_weight import compute_class_weight

# tinh class weight tren tap train
classes = np.array([0, 1])
weights = compute_class_weight(class_weight="balanced", classes=classes, y=train_data["label"])
class_weight = {0: weights[0], 1: weights[1]}

# gan sample_weight cho tung dong
train_data["sample_weight"] = train_data["label"].map(class_weight)
validation_data["sample_weight"] = validation_data["label"].map(class_weight)
test_data["sample_weight"] = test_data["label"].map(class_weight)

# Convert the dataset into a TensorFlow dataset.
train_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    train_data, label="label", weight="sample_weight"
)         
val_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    validation_data, label="label", weight="sample_weight"
)
test_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    test_data, label="label", weight="sample_weight"
)
# Out:
# 2026-09-12 10:36:25.718272: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:984] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2026-09-12 10:36:25.720734: W tensorflow/core/common_runtime/gpu/gpu_device.cc:2251] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...

# %%
import keras

# %%
# %%time

# Train a Random Forest model.
model = tfdf.keras.RandomForestModel()

# Add evaluation metrics
model.compile(
    metrics=["accuracy"]
)
model.fit(x=train_ds)

# # Train a Gradient Boosted Trees model.
# model = tfdf.keras.GradientBoostedTreesModel(num_trees=1500)
# model.fit(train_ds)
# Out:
# Use /tmp/tmp0jh5vnn6 as temporary training directory
# Reading training dataset...
# Training dataset read in 0:00:03.793217. Found 7617 examples.
# Training model...
# Model trained in 0:00:00.901300
# Compiling model...
# [INFO 26-09-12 10:36:31.0024 UTC kernel.cc:1233] Loading model from path /tmp/tmp0jh5vnn6/model/ with prefix a5065261ac254322
# [INFO 26-09-12 10:36:31.0757 UTC decision_forest.cc:734] Model loaded with 300 root(s), 62286 node(s), and 93 input feature(s).
# [INFO 26-09-12 10:36:31.0757 UTC abstract_model.cc:1362] Engine "RandomForestOptPred" built
# [INFO 26-09-12 10:36:31.0757 UTC kernel.cc:1061] Use fast generic engine
# Model compiled.
# CPU times: user 13.8 s, sys: 157 ms, total: 13.9 s
# Wall time: 9.6 s

# %%
# Evaluate the model
evaluate = model.evaluate(val_ds, return_dict=True)
print()

for name, value in evaluate.items():
    print(f"{name}: {value:.4f}")
# Out:
# WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 1/2 [==============>...............] - ETA: 3s - loss: 0.0000e+00 - accuracy: 0.9920
# 2/2 [==============================] - 3s 9ms/step - loss: 0.0000e+00 - accuracy: 0.9926
# loss: 0.0000
# accuracy: 0.9926

# %%
# Model Summary
model.summary()
# Out:
# Model: "random_forest_model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
# =================================================================
# Total params: 1 (1.00 Byte)
# Trainable params: 0 (0.00 Byte)
# Non-trainable params: 1 (1.00 Byte)
# _________________________________________________________________
# Type: "RANDOM_FOREST"
# Task: CLASSIFICATION
# Label: "__LABEL"
#
# Input Features (93):
# 	10Percentile
# 	90Percentile
# 	Autocorrelation
# 	Busyness
# 	ClusterProminence
# 	ClusterShade
# 	ClusterTendency
# 	Coarseness
# 	Complexity
# 	Contrast
# 	Contrast.1
# 	Correlation
# 	DependenceEntropy
# 	DependenceNonUniformity
# 	DependenceNonUniformityNormalized
# 	DependenceVariance
# 	DifferenceAverage
# 	DifferenceEntropy
# 	DifferenceVariance
# 	Energy
# 	Entropy
# 	GrayLevelNonUniformity
# 	GrayLevelNonUniformity.1
# 	GrayLevelNonUniformity.2
# 	GrayLevelNonUniformityNormalized
# 	GrayLevelNonUniformityNormalized.1
# 	GrayLevelVariance
# 	GrayLevelVariance.1
# 	GrayLevelVariance.2
# 	HighGrayLevelEmphasis
# 	HighGrayLevelRunEmphasis
# 	HighGrayLevelZoneEmphasis
# 	Id
# 	Idm
# 	Idmn
# 	Idn
# 	Imc1
# 	Imc2
# 	InterquartileRange
# 	InverseVariance
# 	JointAverage
# 	JointEnergy
# 	JointEntropy
# 	Kurtosis
# 	LargeAreaEmphasis
# 	LargeAreaHighGrayLevelEmphasis
# 	LargeAreaLowGrayLevelEmphasis
# 	LargeDependenceEmphasis
# 	LargeDependenceHighGrayLevelEmphasis
# 	LargeDependenceLowGrayLevelEmphasis
# 	LongRunEmphasis
# 	LongRunHighGrayLevelEmphasis
# 	LongRunLowGrayLevelEmphasis
# 	LowGrayLevelEmphasis
# 	LowGrayLevelRunEmphasis
# 	LowGrayLevelZoneEmphasis
# 	MCC
# 	Maximum
# 	MaximumProbability
# 	Mean
# 	MeanAbsoluteDeviation
# 	Median
# 	Minimum
# 	Range
# 	RobustMeanAbsoluteDeviation
# 	RootMeanSquared
# 	RunEntropy
# 	RunLengthNonUniformity
# 	RunLengthNonUniformityNormalized
# 	RunPercentage
# 	RunVariance
# 	ShortRunEmphasis
# 	ShortRunHighGrayLevelEmphasis
# 	ShortRunLowGrayLevelEmphasis
# 	SizeZoneNonUniformity
# 	SizeZoneNonUniformityNormalized
# 	Skewness
# 	SmallAreaEmphasis
# 	SmallAreaHighGrayLevelEmphasis
# 	SmallAreaLowGrayLevelEmphasis
# 	SmallDependenceEmphasis
# 	SmallDependenceHighGrayLevelEmphasis
# 	SmallDependenceLowGrayLevelEmphasis
# 	Strength
# 	SumAverage
# 	SumEntropy
# 	SumSquares
# 	TotalEnergy
# 	Uniformity
# 	Variance
# 	ZoneEntropy
# 	ZonePercentage
# 	ZoneVariance
#
# Trained with weights
#
# Variable Importance: INV_MEAN_MIN_DEPTH:
#     1.         "LongRunHighGrayLevelEmphasis"  0.131943 ################
#     2. "LargeDependenceHighGrayLevelEmphasis"  0.123980 ###########
#     3.                           "Coarseness"  0.119938 ########
#     4.             "GrayLevelNonUniformity.2"  0.119027 ########
#     5.                           "SumAverage"  0.118104 #######
#     6.                         "90Percentile"  0.118023 #######
#     7.                          "TotalEnergy"  0.117854 #######
#     8.                                 "Mean"  0.117723 #######
#     9.                      "Autocorrelation"  0.117656 #######
#    10.                             "Busyness"  0.117280 #######
#    11.       "LargeAreaHighGrayLevelEmphasis"  0.117227 #######
#    12.                               "Median"  0.117178 #######
#    13.            "HighGrayLevelZoneEmphasis"  0.116648 ######
#    14.                         "JointAverage"  0.115912 ######
#    15.                               "Energy"  0.115688 ######
#    16.                "HighGrayLevelEmphasis"  0.115535 ######
#    17.                                  "Idn"  0.114730 #####
#    18.                                 "Idmn"  0.114612 #####
#    19.  "SmallDependenceLowGrayLevelEmphasis"  0.114249 #####
#    20.             "HighGrayLevelRunEmphasis"  0.113540 ####
#    21.        "ShortRunHighGrayLevelEmphasis"  0.112809 ####
#    22.                      "RootMeanSquared"  0.112766 ####
#    23.                              "Maximum"  0.111990 ####
#    24.                          "Correlation"  0.111847 ###
#    25.                             "Skewness"  0.111473 ###
#    26.         "ShortRunLowGrayLevelEmphasis"  0.111228 ###
#    27.       "SmallAreaHighGrayLevelEmphasis"  0.110960 ###
#    28.                 "LowGrayLevelEmphasis"  0.110601 ###
#    29.                         "10Percentile"  0.110439 ###
#    30.        "SmallAreaLowGrayLevelEmphasis"  0.110144 ##
#    31.              "LowGrayLevelRunEmphasis"  0.109922 ##
#    32.             "LowGrayLevelZoneEmphasis"  0.109900 ##
#    33.          "LongRunLowGrayLevelEmphasis"  0.109710 ##
#    34.                         "ClusterShade"  0.109308 ##
#    35.                              "Minimum"  0.108991 ##
#    36.  "LargeDependenceLowGrayLevelEmphasis"  0.108899 ##
#    37.                                 "Imc1"  0.108887 ##
#    38.                      "InverseVariance"  0.108860 ##
#    39.                    "DependenceEntropy"  0.108463 #
#    40.                                  "MCC"  0.108404 #
#    41.                             "Strength"  0.108280 #
#    42.              "DependenceNonUniformity"  0.107969 #
#    43.              "SmallDependenceEmphasis"  0.107823 #
#    44.                                 "Imc2"  0.107785 #
#    45.                          "RunVariance"  0.107729 #
#    46. "SmallDependenceHighGrayLevelEmphasis"  0.107721 #
#    47.                "SizeZoneNonUniformity"  0.107609 #
#    48.      "SizeZoneNonUniformityNormalized"  0.107597 #
#    49.                   "DependenceVariance"  0.107138 #
#    50.                           "SumEntropy"  0.107057 #
#    51.                      "LongRunEmphasis"  0.107054 #
#    52.                             "Contrast"  0.106921 #
#    53.                                   "Id"  0.106913 #
#    54.                                  "Idm"  0.106907 #
#    55.        "LargeAreaLowGrayLevelEmphasis"  0.106881 #
#    56.    "DependenceNonUniformityNormalized"  0.106870 #
#    57.                    "DifferenceEntropy"  0.106862 #
#    58.               "GrayLevelNonUniformity"  0.106857
#    59.                           "Contrast.1"  0.106812
#    60.                    "SmallAreaEmphasis"  0.106793
#    61.                       "ZonePercentage"  0.106696
#    62.     "RunLengthNonUniformityNormalized"  0.106401
#    63.                           "RunEntropy"  0.106230
#    64.                             "Kurtosis"  0.106225
#    65.                                "Range"  0.106167
#    66.               "RunLengthNonUniformity"  0.106098
#    67.                           "Uniformity"  0.106063
#    68.                    "DifferenceAverage"  0.105995
#    69.                     "ShortRunEmphasis"  0.105986
#    70.     "GrayLevelNonUniformityNormalized"  0.105967
#    71.                   "MaximumProbability"  0.105961
#    72.             "GrayLevelNonUniformity.1"  0.105953
#    73.              "LargeDependenceEmphasis"  0.105914
#    74.                   "DifferenceVariance"  0.105899
#    75.                        "RunPercentage"  0.105759
#    76.                           "Complexity"  0.105723
#    77.                    "LargeAreaEmphasis"  0.105654
#    78.                         "ZoneVariance"  0.105616
#    79.                           "SumSquares"  0.105582
#    80.                    "ClusterProminence"  0.105580
#    81.                      "ClusterTendency"  0.105563
#    82.                   "InterquartileRange"  0.105540
#    83.                          "ZoneEntropy"  0.105528
#    84.                  "GrayLevelVariance.2"  0.105512
#    85.                              "Entropy"  0.105493
#    86.                             "Variance"  0.105368
#    87.   "GrayLevelNonUniformityNormalized.1"  0.105339
#    88.                "MeanAbsoluteDeviation"  0.105336
#    89.                  "GrayLevelVariance.1"  0.105248
#    90.                          "JointEnergy"  0.105243
#    91.                         "JointEntropy"  0.105238
#    92.          "RobustMeanAbsoluteDeviation"  0.105237
#    93.                    "GrayLevelVariance"  0.105188
#
# Variable Importance: NUM_AS_ROOT:
#     1.         "LongRunHighGrayLevelEmphasis" 31.000000 ################
#     2.            "HighGrayLevelZoneEmphasis" 25.000000 ############
#     3.                          "TotalEnergy" 25.000000 ############
#     4.                           "SumAverage" 20.000000 ##########
#     5.                         "90Percentile" 19.000000 #########
#     6.                      "Autocorrelation" 19.000000 #########
#     7.                "HighGrayLevelEmphasis" 19.000000 #########
#     8.                               "Energy" 18.000000 #########
#     9.             "HighGrayLevelRunEmphasis" 16.000000 ########
#    10.                         "JointAverage" 15.000000 #######
#    11.                                 "Mean" 14.000000 ######
#    12.        "ShortRunHighGrayLevelEmphasis" 11.000000 #####
#    13.                      "RootMeanSquared" 10.000000 ####
#    14.             "LowGrayLevelZoneEmphasis"  6.000000 ##
#    15.         "ShortRunLowGrayLevelEmphasis"  6.000000 ##
#    16.       "SmallAreaHighGrayLevelEmphasis"  6.000000 ##
#    17.        "SmallAreaLowGrayLevelEmphasis"  6.000000 ##
#    18.                              "Maximum"  5.000000 ##
#    19.                 "LowGrayLevelEmphasis"  4.000000 #
#    20.                              "Minimum"  4.000000 #
#    21.              "LowGrayLevelRunEmphasis"  3.000000 #
#    22.                               "Median"  3.000000 #
#    23.                          "Correlation"  2.000000
#    24.               "GrayLevelNonUniformity"  2.000000
#    25.          "LongRunLowGrayLevelEmphasis"  2.000000
#    26.  "SmallDependenceLowGrayLevelEmphasis"  2.000000
#    27.                         "10Percentile"  1.000000
#    28.                             "Busyness"  1.000000
#    29.                           "Coarseness"  1.000000
#    30.       "LargeAreaHighGrayLevelEmphasis"  1.000000
#    31.  "LargeDependenceLowGrayLevelEmphasis"  1.000000
#    32. "SmallDependenceHighGrayLevelEmphasis"  1.000000
#    33.                           "Uniformity"  1.000000
#
# Variable Importance: NUM_NODES:
#     1.                                  "Idn" 1092.000000 ################
#     2.                                 "Idmn" 1075.000000 ###############
#     3.                             "Skewness" 662.000000 ########
#     4.                           "Coarseness" 631.000000 #######
#     5.             "GrayLevelNonUniformity.2" 607.000000 #######
#     6.                             "Busyness" 606.000000 #######
#     7. "LargeDependenceHighGrayLevelEmphasis" 545.000000 ######
#     8.                          "Correlation" 533.000000 ######
#     9.                         "ClusterShade" 528.000000 ######
#    10.         "LongRunHighGrayLevelEmphasis" 523.000000 ######
#    11.                              "Maximum" 510.000000 #####
#    12.                               "Median" 457.000000 ####
#    13.                                  "MCC" 436.000000 ####
#    14.       "LargeAreaHighGrayLevelEmphasis" 419.000000 ####
#    15.  "SmallDependenceLowGrayLevelEmphasis" 411.000000 ####
#    16.       "SmallAreaHighGrayLevelEmphasis" 409.000000 ####
#    17.                         "90Percentile" 405.000000 ###
#    18.                    "DependenceEntropy" 399.000000 ###
#    19.                             "Kurtosis" 383.000000 ###
#    20.        "SmallAreaLowGrayLevelEmphasis" 383.000000 ###
#    21.            "HighGrayLevelZoneEmphasis" 378.000000 ###
#    22.                             "Strength" 370.000000 ###
#    23.                           "Contrast.1" 365.000000 ###
#    24.                              "Minimum" 363.000000 ###
#    25.                                 "Imc1" 356.000000 ###
#    26.                         "JointAverage" 352.000000 ###
#    27.                             "Contrast" 350.000000 ##
#    28.                           "SumAverage" 349.000000 ##
#    29.                                 "Mean" 343.000000 ##
#    30.      "SizeZoneNonUniformityNormalized" 342.000000 ##
#    31.                      "Autocorrelation" 340.000000 ##
#    32.                               "Energy" 331.000000 ##
#    33.                    "SmallAreaEmphasis" 329.000000 ##
#    34.                "SizeZoneNonUniformity" 325.000000 ##
#    35.                "HighGrayLevelEmphasis" 322.000000 ##
#    36.          "LongRunLowGrayLevelEmphasis" 322.000000 ##
#    37.             "LowGrayLevelZoneEmphasis" 322.000000 ##
#    38.              "LowGrayLevelRunEmphasis" 321.000000 ##
#    39.                           "SumEntropy" 320.000000 ##
#    40.        "ShortRunHighGrayLevelEmphasis" 319.000000 ##
#    41.                         "10Percentile" 318.000000 ##
#    42.                                 "Imc2" 318.000000 ##
#    43.                                "Range" 315.000000 ##
#    44.                   "DifferenceVariance" 314.000000 ##
#    45.         "ShortRunLowGrayLevelEmphasis" 313.000000 ##
#    46.                      "InverseVariance" 312.000000 ##
#    47.                   "InterquartileRange" 309.000000 ##
#    48.                 "LowGrayLevelEmphasis" 304.000000 ##
#    49.                   "DependenceVariance" 297.000000 ##
#    50.  "LargeDependenceLowGrayLevelEmphasis" 295.000000 ##
#    51.                          "TotalEnergy" 295.000000 ##
#    52.                      "RootMeanSquared" 294.000000 ##
#    53.                          "RunVariance" 286.000000 #
#    54.             "HighGrayLevelRunEmphasis" 284.000000 #
#    55.                    "DifferenceEntropy" 282.000000 #
#    56.        "LargeAreaLowGrayLevelEmphasis" 279.000000 #
#    57. "SmallDependenceHighGrayLevelEmphasis" 277.000000 #
#    58.              "SmallDependenceEmphasis" 271.000000 #
#    59.                                  "Idm" 268.000000 #
#    60.                           "Uniformity" 266.000000 #
#    61.                           "Complexity" 265.000000 #
#    62.                    "DifferenceAverage" 250.000000 #
#    63.              "DependenceNonUniformity" 249.000000 #
#    64.               "GrayLevelNonUniformity" 249.000000 #
#    65.                   "MaximumProbability" 247.000000 #
#    66.                      "LongRunEmphasis" 241.000000 #
#    67.             "GrayLevelNonUniformity.1" 240.000000 #
#    68.   "GrayLevelNonUniformityNormalized.1" 240.000000 #
#    69.    "DependenceNonUniformityNormalized" 238.000000 #
#    70.                           "RunEntropy" 237.000000 #
#    71.                  "GrayLevelVariance.2" 234.000000
#    72.          "RobustMeanAbsoluteDeviation" 231.000000
#    73.     "GrayLevelNonUniformityNormalized" 227.000000
#    74.                                   "Id" 226.000000
#    75.                          "ZoneEntropy" 225.000000
#    76.                       "ZonePercentage" 221.000000
#    77.                          "JointEnergy" 218.000000
#    78.              "LargeDependenceEmphasis" 218.000000
#    79.                "MeanAbsoluteDeviation" 215.000000
#    80.                    "ClusterProminence" 214.000000
#    81.                      "ClusterTendency" 214.000000
#    82.                           "SumSquares" 211.000000
#    83.                              "Entropy" 205.000000
#    84.     "RunLengthNonUniformityNormalized" 205.000000
#    85.                             "Variance" 205.000000
#    86.                         "ZoneVariance" 203.000000
#    87.                    "LargeAreaEmphasis" 198.000000
#    88.                     "ShortRunEmphasis" 198.000000
#    89.               "RunLengthNonUniformity" 196.000000
#    90.                    "GrayLevelVariance" 192.000000
#    91.                        "RunPercentage" 189.000000
#    92.                  "GrayLevelVariance.1" 183.000000
#    93.                         "JointEntropy" 179.000000
#
# Variable Importance: SUM_SCORE:
#     1.         "LongRunHighGrayLevelEmphasis" 95664.485625 ################
#     2.                          "TotalEnergy" 64409.441282 ##########
#     3.            "HighGrayLevelZoneEmphasis" 62183.263868 ##########
#     4.                           "SumAverage" 55557.141492 #########
#     5.                      "Autocorrelation" 55296.672413 #########
#     6.                         "90Percentile" 53109.608740 ########
#     7.                "HighGrayLevelEmphasis" 50326.787664 ########
#     8.                               "Energy" 47837.729615 #######
#     9.                                 "Mean" 45805.175590 #######
#    10.                         "JointAverage" 43972.118424 #######
#    11. "LargeDependenceHighGrayLevelEmphasis" 42122.236666 ######
#    12.             "HighGrayLevelRunEmphasis" 41629.211047 ######
#    13.                                  "Idn" 35237.877749 #####
#    14.                                 "Idmn" 34327.858987 #####
#    15.        "ShortRunHighGrayLevelEmphasis" 33285.417096 #####
#    16.                      "RootMeanSquared" 32808.034182 #####
#    17.                           "Coarseness" 29359.361182 ####
#    18.             "GrayLevelNonUniformity.2" 28308.741073 ####
#    19.                             "Busyness" 26970.228565 ####
#    20.                              "Maximum" 26291.088225 ###
#    21.                               "Median" 25133.799584 ###
#    22.       "LargeAreaHighGrayLevelEmphasis" 24688.255384 ###
#    23.       "SmallAreaHighGrayLevelEmphasis" 22691.571532 ###
#    24.         "ShortRunLowGrayLevelEmphasis" 21745.131874 ###
#    25.  "SmallDependenceLowGrayLevelEmphasis" 21049.841785 ###
#    26.             "LowGrayLevelZoneEmphasis" 21000.106964 ###
#    27.        "SmallAreaLowGrayLevelEmphasis" 19656.478604 ##
#    28.                 "LowGrayLevelEmphasis" 17802.942219 ##
#    29.                          "Correlation" 16220.105702 ##
#    30.                             "Skewness" 15216.990133 ##
#    31.              "LowGrayLevelRunEmphasis" 14779.943327 #
#    32.                              "Minimum" 12760.732316 #
#    33.                         "10Percentile" 12317.405837 #
#    34.          "LongRunLowGrayLevelEmphasis" 11964.479840 #
#    35.                         "ClusterShade" 11956.732033 #
#    36.                                 "Imc1" 11091.044187 #
#    37.                      "InverseVariance" 10064.918601 #
#    38.  "LargeDependenceLowGrayLevelEmphasis" 10042.466850 #
#    39.                    "DependenceEntropy" 10013.147858 #
#    40. "SmallDependenceHighGrayLevelEmphasis" 9798.506929 #
#    41.                             "Strength" 9488.831509 #
#    42.                                  "MCC" 9078.978662
#    43.                                 "Imc2" 9059.942473
#    44.                           "SumEntropy" 8583.871343
#    45.                "SizeZoneNonUniformity" 8397.188210
#    46.      "SizeZoneNonUniformityNormalized" 8069.953400
#    47.                             "Contrast" 7828.453786
#    48.              "SmallDependenceEmphasis" 7702.076630
#    49.                          "RunVariance" 7666.636548
#    50.                           "Contrast.1" 7381.358782
#    51.                    "SmallAreaEmphasis" 7371.788820
#    52.              "DependenceNonUniformity" 7086.560379
#    53.                   "DependenceVariance" 7051.341876
#    54.                                  "Idm" 7038.889207
#    55.                      "LongRunEmphasis" 6664.367921
#    56.        "LargeAreaLowGrayLevelEmphasis" 6571.571377
#    57.                                   "Id" 6567.198014
#    58.                    "DifferenceEntropy" 6191.134452
#    59.                                "Range" 6111.500457
#    60.                             "Kurtosis" 6094.106620
#    61.    "DependenceNonUniformityNormalized" 6060.106760
#    62.                   "DifferenceVariance" 5985.100659
#    63.                           "RunEntropy" 5950.488171
#    64.                       "ZonePercentage" 5872.577636
#    65.                    "DifferenceAverage" 5632.127282
#    66.               "GrayLevelNonUniformity" 5587.451175
#    67.                           "Complexity" 5476.503661
#    68.     "RunLengthNonUniformityNormalized" 5463.960467
#    69.                     "ShortRunEmphasis" 5338.566380
#    70.             "GrayLevelNonUniformity.1" 5187.324027
#    71.                           "Uniformity" 5121.315075
#    72.                   "InterquartileRange" 5103.961142
#    73.               "RunLengthNonUniformity" 4938.898848
#    74.                        "RunPercentage" 4762.925520
#    75.              "LargeDependenceEmphasis" 4494.786912
#    76.                   "MaximumProbability" 4488.651311
#    77.                              "Entropy" 4436.208805
#    78.     "GrayLevelNonUniformityNormalized" 4300.744095
#    79.                      "ClusterTendency" 4286.221091
#    80.                          "ZoneEntropy" 4267.113591
#    81.                           "SumSquares" 4187.213459
#    82.   "GrayLevelNonUniformityNormalized.1" 4185.687434
#    83.                         "ZoneVariance" 4059.229531
#    84.                    "LargeAreaEmphasis" 3980.329497
#    85.                "MeanAbsoluteDeviation" 3942.307019
#    86.                          "JointEnergy" 3896.564151
#    87.                             "Variance" 3785.762085
#    88.                    "ClusterProminence" 3780.944916
#    89.                  "GrayLevelVariance.2" 3775.866106
#    90.                    "GrayLevelVariance" 3538.721766
#    91.                  "GrayLevelVariance.1" 3522.997886
#    92.          "RobustMeanAbsoluteDeviation" 3412.225751
#    93.                         "JointEntropy" 3382.871105
#
#
#
# Winner takes all: true
# Out-of-bag evaluation: accuracy:0.86588 logloss:0.396901
# Number of trees: 300
# Total number of nodes: 62286
#
# Number of nodes by tree:
# Count: 300 Average: 207.62 StdDev: 12.1162
# Min: 175 Max: 243 Ignored: 0
# ----------------------------------------------
# [ 175, 178)  4   1.33%   1.33% #
# [ 178, 181)  1   0.33%   1.67%
# [ 181, 185)  2   0.67%   2.33%
# [ 185, 188)  5   1.67%   4.00% #
# [ 188, 192) 15   5.00%   9.00% ###
# [ 192, 195) 13   4.33%  13.33% ###
# [ 195, 199) 20   6.67%  20.00% #####
# [ 199, 202) 37  12.33%  32.33% #########
# [ 202, 206) 43  14.33%  46.67% ##########
# [ 206, 209) 18   6.00%  52.67% ####
# [ 209, 212) 39  13.00%  65.67% #########
# [ 212, 216) 33  11.00%  76.67% ########
# [ 216, 219)  7   2.33%  79.00% ##
# [ 219, 223) 24   8.00%  87.00% ######
# [ 223, 226) 21   7.00%  94.00% #####
# [ 226, 230)  8   2.67%  96.67% ##
# [ 230, 233)  4   1.33%  98.00% #
# [ 233, 237)  2   0.67%  98.67%
# [ 237, 240)  0   0.00%  98.67%
# [ 240, 243]  4   1.33% 100.00% #
#
# Depth by leafs:
# Count: 31293 Average: 8.60483 StdDev: 2.54438
# Min: 2 Max: 15 Ignored: 0
# ----------------------------------------------
# [  2,  3)   18   0.06%   0.06%
# [  3,  4)  472   1.51%   1.57% #
# [  4,  5)  911   2.91%   4.48% ##
# [  5,  6) 1987   6.35%  10.83% ####
# [  6,  7) 3220  10.29%  21.12% #######
# [  7,  8) 4269  13.64%  34.76% #########
# [  8,  9) 4908  15.68%  50.44% ##########
# [  9, 10) 4484  14.33%  64.77% #########
# [ 10, 11) 3839  12.27%  77.04% ########
# [ 11, 12) 2971   9.49%  86.53% ######
# [ 12, 13) 1977   6.32%  92.85% ####
# [ 13, 14) 1142   3.65%  96.50% ##
# [ 14, 15)  649   2.07%  98.57% #
# [ 15, 15]  446   1.43% 100.00% #
#
# Number of training obs by leaf:
# Count: 31293 Average: 73.0227 StdDev: 240.702
# Min: 5 Max: 3176 Ignored: 0
# ----------------------------------------------
# [    5,  163) 28548  91.23%  91.23% ##########
# [  163,  322)  1206   3.85%  95.08%
# [  322,  480)   403   1.29%  96.37%
# [  480,  639)   227   0.73%  97.10%
# [  639,  798)   149   0.48%  97.57%
# [  798,  956)   118   0.38%  97.95%
# [  956, 1115)   112   0.36%  98.31%
# [ 1115, 1273)    98   0.31%  98.62%
# [ 1273, 1432)   100   0.32%  98.94%
# [ 1432, 1591)    80   0.26%  99.19%
# [ 1591, 1749)    78   0.25%  99.44%
# [ 1749, 1908)    61   0.19%  99.64%
# [ 1908, 2066)    41   0.13%  99.77%
# [ 2066, 2225)    36   0.12%  99.88%
# [ 2225, 2384)    20   0.06%  99.95%
# [ 2384, 2542)     5   0.02%  99.96%
# [ 2542, 2701)     6   0.02%  99.98%
# [ 2701, 2859)     3   0.01%  99.99%
# [ 2859, 3018)     1   0.00% 100.00%
# [ 3018, 3176]     1   0.00% 100.00%
#
# Attribute in nodes:
# 	1092 : Idn [NUMERICAL]
# 	1075 : Idmn [NUMERICAL]
# 	662 : Skewness [NUMERICAL]
# 	631 : Coarseness [NUMERICAL]
# 	607 : GrayLevelNonUniformity.2 [NUMERICAL]
# 	606 : Busyness [NUMERICAL]
# 	545 : LargeDependenceHighGrayLevelEmphasis [NUMERICAL]
# 	533 : Correlation [NUMERICAL]
# 	528 : ClusterShade [NUMERICAL]
# 	523 : LongRunHighGrayLevelEmphasis [NUMERICAL]
# 	510 : Maximum [NUMERICAL]
# 	457 : Median [NUMERICAL]
# 	436 : MCC [NUMERICAL]
# 	419 : LargeAreaHighGrayLevelEmphasis [NUMERICAL]
# 	411 : SmallDependenceLowGrayLevelEmphasis [NUMERICAL]
# 	409 : SmallAreaHighGrayLevelEmphasis [NUMERICAL]
# 	405 : 90Percentile [NUMERICAL]
# 	399 : DependenceEntropy [NUMERICAL]
# 	383 : SmallAreaLowGrayLevelEmphasis [NUMERICAL]
# 	383 : Kurtosis [NUMERICAL]
# 	378 : HighGrayLevelZoneEmphasis [NUMERICAL]
# 	370 : Strength [NUMERICAL]
# 	365 : Contrast.1 [NUMERICAL]
# 	363 : Minimum [NUMERICAL]
# 	356 : Imc1 [NUMERICAL]
# 	352 : JointAverage [NUMERICAL]
# 	350 : Contrast [NUMERICAL]
# 	349 : SumAverage [NUMERICAL]
# 	343 : Mean [NUMERICAL]
# 	342 : SizeZoneNonUniformityNormalized [NUMERICAL]
# 	340 : Autocorrelation [NUMERICAL]
# 	331 : Energy [NUMERICAL]
# 	329 : SmallAreaEmphasis [NUMERICAL]
# 	325 : SizeZoneNonUniformity [NUMERICAL]
# 	322 : LowGrayLevelZoneEmphasis [NUMERICAL]
# 	322 : LongRunLowGrayLevelEmphasis [NUMERICAL]
# 	322 : HighGrayLevelEmphasis [NUMERICAL]
# 	321 : LowGrayLevelRunEmphasis [NUMERICAL]
# 	320 : SumEntropy [NUMERICAL]
# 	319 : ShortRunHighGrayLevelEmphasis [NUMERICAL]
# 	318 : Imc2 [NUMERICAL]
# 	318 : 10Percentile [NUMERICAL]
# 	315 : Range [NUMERICAL]
# 	314 : DifferenceVariance [NUMERICAL]
# 	313 : ShortRunLowGrayLevelEmphasis [NUMERICAL]
# 	312 : InverseVariance [NUMERICAL]
# 	309 : InterquartileRange [NUMERICAL]
# 	304 : LowGrayLevelEmphasis [NUMERICAL]
# 	297 : DependenceVariance [NUMERICAL]
# 	295 : TotalEnergy [NUMERICAL]
# 	295 : LargeDependenceLowGrayLevelEmphasis [NUMERICAL]
# 	294 : RootMeanSquared [NUMERICAL]
# 	286 : RunVariance [NUMERICAL]
# 	284 : HighGrayLevelRunEmphasis [NUMERICAL]
# 	282 : DifferenceEntropy [NUMERICAL]
# 	279 : LargeAreaLowGrayLevelEmphasis [NUMERICAL]
# 	277 : SmallDependenceHighGrayLevelEmphasis [NUMERICAL]
# 	271 : SmallDependenceEmphasis [NUMERICAL]
# 	268 : Idm [NUMERICAL]
# 	266 : Uniformity [NUMERICAL]
# 	265 : Complexity [NUMERICAL]
# 	250 : DifferenceAverage [NUMERICAL]
# 	249 : GrayLevelNonUniformity [NUMERICAL]
# 	249 : DependenceNonUniformity [NUMERICAL]
# 	247 : MaximumProbability [NUMERICAL]
# 	241 : LongRunEmphasis [NUMERICAL]
# 	240 : GrayLevelNonUniformityNormalized.1 [NUMERICAL]
# 	240 : GrayLevelNonUniformity.1 [NUMERICAL]
# 	238 : DependenceNonUniformityNormalized [NUMERICAL]
# 	237 : RunEntropy [NUMERICAL]
# 	234 : GrayLevelVariance.2 [NUMERICAL]
# 	231 : RobustMeanAbsoluteDeviation [NUMERICAL]
# 	227 : GrayLevelNonUniformityNormalized [NUMERICAL]
# 	226 : Id [NUMERICAL]
# 	225 : ZoneEntropy [NUMERICAL]
# 	221 : ZonePercentage [NUMERICAL]
# 	218 : LargeDependenceEmphasis [NUMERICAL]
# 	218 : JointEnergy [NUMERICAL]
# 	215 : MeanAbsoluteDeviation [NUMERICAL]
# 	214 : ClusterTendency [NUMERICAL]
# 	214 : ClusterProminence [NUMERICAL]
# 	211 : SumSquares [NUMERICAL]
# 	205 : Variance [NUMERICAL]
# 	205 : RunLengthNonUniformityNormalized [NUMERICAL]
# 	205 : Entropy [NUMERICAL]
# 	203 : ZoneVariance [NUMERICAL]
# 	198 : ShortRunEmphasis [NUMERICAL]
# 	198 : LargeAreaEmphasis [NUMERICAL]
# 	196 : RunLengthNonUniformity [NUMERICAL]
# 	192 : GrayLevelVariance [NUMERICAL]
# 	189 : RunPercentage [NUMERICAL]
# 	183 : GrayLevelVariance.1 [NUMERICAL]
# 	179 : JointEntropy [NUMERICAL]
#
# Attribute in nodes with depth <= 0:
# 	31 : LongRunHighGrayLevelEmphasis [NUMERICAL]
# 	25 : TotalEnergy [NUMERICAL]
# 	25 : HighGrayLevelZoneEmphasis [NUMERICAL]
# 	20 : SumAverage [NUMERICAL]
# 	19 : HighGrayLevelEmphasis [NUMERICAL]
# 	19 : Autocorrelation [NUMERICAL]
# 	19 : 90Percentile [NUMERICAL]
# 	18 : Energy [NUMERICAL]
# 	16 : HighGrayLevelRunEmphasis [NUMERICAL]
# 	15 : JointAverage [NUMERICAL]
# 	14 : Mean [NUMERICAL]
# 	11 : ShortRunHighGrayLevelEmphasis [NUMERICAL]
# 	10 : RootMeanSquared [NUMERICAL]
# 	6 : SmallAreaLowGrayLevelEmphasis [NUMERICAL]
# 	6 : SmallAreaHighGrayLevelEmphasis [NUMERICAL]
# 	6 : ShortRunLowGrayLevelEmphasis [NUMERICAL]
# 	6 : LowGrayLevelZoneEmphasis [NUMERICAL]
# 	5 : Maximum [NUMERICAL]
# 	4 : Minimum [NUMERICAL]
# 	4 : LowGrayLevelEmphasis [NUMERICAL]
# 	3 : Median [NUMERICAL]
# 	3 : LowGrayLevelRunEmphasis [NUMERICAL]
# 	2 : SmallDependenceLowGrayLevelEmphasis [NUMERICAL]
# 	2 : LongRunLowGrayLevelEmphasis [NUMERICAL]
# 	2 : GrayLevelNonUniformity [NUMERICAL]
# 	2 : Correlation [NUMERICAL]
# 	1 : Uniformity [NUMERICAL]
# 	1 : SmallDependenceHighGrayLevelEmphasis [NUMERICAL]
# 	1 : LargeDependenceLowGrayLevelEmphasis [NUMERICAL]
# 	1 : LargeAreaHighGrayLevelEmphasis [NUMERICAL]
# 	1 : Coarseness [NUMERICAL]
# 	1 : Busyness [NUMERICAL]
# 	1 : 10Percentile [NUMERICAL]
#
# Attribute in nodes with depth <= 1:
# 	77 : LongRunHighGrayLevelEmphasis [NUMERICAL]
# 	58 : Mean [NUMERICAL]
# 	58 : Autocorrelation [NUMERICAL]
# 	49 : SumAverage [NUMERICAL]
# 	47 : HighGrayLevelEmphasis [NUMERICAL]
# 	44 : TotalEnergy [NUMERICAL]
# 	42 : JointAverage [NUMERICAL]
# 	36 : HighGrayLevelRunEmphasis [NUMERICAL]
# 	33 : HighGrayLevelZoneEmphasis [NUMERICAL]
# 	33 : Energy [NUMERICAL]
# 	31 : LargeDependenceHighGrayLevelEmphasis [NUMERICAL]
# 	29 : Median [NUMERICAL]
# 	29 : 90Percentile [NUMERICAL]
# 	28 : ShortRunHighGrayLevelEmphasis [NUMERICAL]
# 	26 : LargeAreaHighGrayLevelEmphasis [NUMERICAL]
# 	25 : RootMeanSquared [NUMERICAL]
# 	24 : SmallDependenceLowGrayLevelEmphasis [NUMERICAL]
# 	24 : Coarseness [NUMERICAL]
# 	22 : ShortRunLowGrayLevelEmphasis [NUMERICAL]
# 	21 : LowGrayLevelEmphasis [NUMERICAL]
# 	16 : GrayLevelNonUniformity.2 [NUMERICAL]
# 	14 : SmallAreaLowGrayLevelEmphasis [NUMERICAL]
# 	14 : LowGrayLevelZoneEmphasis [NUMERICAL]
# 	14 : LowGrayLevelRunEmphasis [NUMERICAL]
# 	14 : 10Percentile [NUMERICAL]
# 	12 : Busyness [NUMERICAL]
# 	11 : SmallAreaHighGrayLevelEmphasis [NUMERICAL]
# 	11 : Maximum [NUMERICAL]
# 	11 : LongRunLowGrayLevelEmphasis [NUMERICAL]
# 	7 : LargeDependenceLowGrayLevelEmphasis [NUMERICAL]
# 	5 : Minimum [NUMERICAL]
# 	5 : InverseVariance [NUMERICAL]
# 	4 : SmallDependenceEmphasis [NUMERICAL]
# 	4 : DependenceNonUniformity [NUMERICAL]
# 	3 : DifferenceEntropy [NUMERICAL]
# 	3 : Correlation [NUMERICAL]
# 	2 : SmallDependenceHighGrayLevelEmphasis [NUMERICAL]
# 	2 : SizeZoneNonUniformityNormalized [NUMERICAL]
# 	2 : LargeAreaLowGrayLevelEmphasis [NUMERICAL]
# 	2 : GrayLevelNonUniformity [NUMERICAL]
# 	2 : DependenceNonUniformityNormalized [NUMERICAL]
# 	1 : ZonePercentage [NUMERICAL]
# 	1 : Uniformity [NUMERICAL]
# 	1 : Strength [NUMERICAL]
# 	1 : SizeZoneNonUniformity [NUMERICAL]
# 	1 : Contrast.1 [NUMERICAL]
# 	1 : Contrast [NUMERICAL]
#
# Attribute in nodes with depth <= 2:
# 	129 : LongRunHighGrayLevelEmphasis [NUMERICAL]
# 	91 : Median [NUMERICAL]
# 	83 : Autocorrelation [NUMERICAL]
# 	82 : Mean [NUMERICAL]
# 	82 : JointAverage [NUMERICAL]
# 	81 : SumAverage [NUMERICAL]
# 	78 : LargeDependenceHighGrayLevelEmphasis [NUMERICAL]
# 	70 : HighGrayLevelEmphasis [NUMERICAL]
# 	70 : Energy [NUMERICAL]
# 	63 : TotalEnergy [NUMERICAL]
# 	59 : Coarseness [NUMERICAL]
# 	58 : GrayLevelNonUniformity.2 [NUMERICAL]
# 	56 : 90Percentile [NUMERICAL]
# 	52 : RootMeanSquared [NUMERICAL]
# 	52 : LargeAreaHighGrayLevelEmphasis [NUMERICAL]
# 	50 : Skewness [NUMERICAL]
# 	48 : ShortRunHighGrayLevelEmphasis [NUMERICAL]
# 	48 : HighGrayLevelRunEmphasis [NUMERICAL]
# 	43 : HighGrayLevelZoneEmphasis [NUMERICAL]
# 	40 : ShortRunLowGrayLevelEmphasis [NUMERICAL]
# 	39 : Busyness [NUMERICAL]
# 	38 : SmallDependenceLowGrayLevelEmphasis [NUMERICAL]
# 	37 : LowGrayLevelEmphasis [NUMERICAL]
# 	35 : Correlation [NUMERICAL]
# 	30 : LowGrayLevelRunEmphasis [NUMERICAL]
# 	30 : 10Percentile [NUMERICAL]
# 	26 : SmallAreaLowGrayLevelEmphasis [NUMERICAL]
# 	24 : Maximum [NUMERICAL]
# 	24 : LowGrayLevelZoneEmphasis [NUMERICAL]
# 	23 : Idn [NUMERICAL]
# 	22 : Idmn [NUMERICAL]
# 	21 : LongRunLowGrayLevelEmphasis [NUMERICAL]
# 	21 : DependenceEntropy [NUMERICAL]
# 	20 : ClusterShade [NUMERICAL]
# 	18 : Minimum [NUMERICAL]
# 	17 : SmallAreaHighGrayLevelEmphasis [NUMERICAL]
# 	15 : LargeDependenceLowGrayLevelEmphasis [NUMERICAL]
# 	14 : MCC [NUMERICAL]
# 	14 : LongRunEmphasis [NUMERICAL]
# 	12 : Imc1 [NUMERICAL]
# 	11 : SmallDependenceEmphasis [NUMERICAL]
# 	11 : Imc2 [NUMERICAL]
# 	11 : DependenceNonUniformity [NUMERICAL]
# 	10 : InverseVariance [NUMERICAL]
# 	10 : GrayLevelNonUniformity [NUMERICAL]
# 	10 : DependenceNonUniformityNormalized [NUMERICAL]
# 	9 : ZonePercentage [NUMERICAL]
# 	9 : Uniformity [NUMERICAL]
# 	9 : SmallDependenceHighGrayLevelEmphasis [NUMERICAL]
# 	9 : SizeZoneNonUniformity [NUMERICAL]
# 	9 : RunVariance [NUMERICAL]
# 	9 : RunLengthNonUniformityNormalized [NUMERICAL]
# 	9 : Id [NUMERICAL]
# 	8 : SizeZoneNonUniformityNormalized [NUMERICAL]
# 	7 : Strength [NUMERICAL]
# 	7 : RunLengthNonUniformity [NUMERICAL]
# 	7 : LargeAreaLowGrayLevelEmphasis [NUMERICAL]
# 	6 : ZoneVariance [NUMERICAL]
# 	6 : GrayLevelNonUniformityNormalized [NUMERICAL]
# 	6 : GrayLevelNonUniformity.1 [NUMERICAL]
# 	6 : DifferenceEntropy [NUMERICAL]
# 	6 : DependenceVariance [NUMERICAL]
# 	5 : MaximumProbability [NUMERICAL]
# 	5 : LargeAreaEmphasis [NUMERICAL]
# 	5 : Idm [NUMERICAL]
# 	5 : Contrast.1 [NUMERICAL]
# 	4 : Variance [NUMERICAL]
# 	4 : SumEntropy [NUMERICAL]
# 	4 : ShortRunEmphasis [NUMERICAL]
# 	4 : RunPercentage [NUMERICAL]
# 	4 : RunEntropy [NUMERICAL]
# 	4 : Kurtosis [NUMERICAL]
# 	4 : Contrast [NUMERICAL]
# 	3 : ZoneEntropy [NUMERICAL]
# 	3 : SmallAreaEmphasis [NUMERICAL]
# 	3 : LargeDependenceEmphasis [NUMERICAL]
# 	3 : InterquartileRange [NUMERICAL]
# 	3 : Entropy [NUMERICAL]
# 	2 : SumSquares [NUMERICAL]
# 	2 : Range [NUMERICAL]
# 	2 : JointEntropy [NUMERICAL]
# 	2 : JointEnergy [NUMERICAL]
# 	2 : GrayLevelVariance.2 [NUMERICAL]
# 	2 : DifferenceVariance [NUMERICAL]
# 	2 : DifferenceAverage [NUMERICAL]
# 	2 : Complexity [NUMERICAL]
# 	2 : ClusterTendency [NUMERICAL]
# 	1 : GrayLevelNonUniformityNormalized.1 [NUMERICAL]
#
# Attribute in nodes with depth <= 3:
# 	177 : LongRunHighGrayLevelEmphasis [NUMERICAL]
# 	128 : LargeDependenceHighGrayLevelEmphasis [NUMERICAL]
# 	122 : Median [NUMERICAL]
# 	121 : Coarseness [NUMERICAL]
# 	114 : Mean [NUMERICAL]
# 	111 : JointAverage [NUMERICAL]
# 	110 : GrayLevelNonUniformity.2 [NUMERICAL]
# 	107 : SumAverage [NUMERICAL]
# 	107 : Skewness [NUMERICAL]
# 	106 : Autocorrelation [NUMERICAL]
# 	92 : TotalEnergy [NUMERICAL]
# 	89 : HighGrayLevelEmphasis [NUMERICAL]
# 	87 : Busyness [NUMERICAL]
# 	87 : 90Percentile [NUMERICAL]
# 	86 : Energy [NUMERICAL]
# 	82 : LargeAreaHighGrayLevelEmphasis [NUMERICAL]
# 	81 : Correlation [NUMERICAL]
# 	70 : ShortRunHighGrayLevelEmphasis [NUMERICAL]
# 	70 : HighGrayLevelZoneEmphasis [NUMERICAL]
# 	68 : RootMeanSquared [NUMERICAL]
# 	67 : Idmn [NUMERICAL]
# 	66 : SmallDependenceLowGrayLevelEmphasis [NUMERICAL]
# 	66 : ShortRunLowGrayLevelEmphasis [NUMERICAL]
# 	64 : Idn [NUMERICAL]
# 	60 : HighGrayLevelRunEmphasis [NUMERICAL]
# 	59 : ClusterShade [NUMERICAL]
# 	57 : MCC [NUMERICAL]
# 	57 : LowGrayLevelEmphasis [NUMERICAL]
# 	55 : Maximum [NUMERICAL]
# 	54 : SmallAreaHighGrayLevelEmphasis [NUMERICAL]
# 	52 : DependenceEntropy [NUMERICAL]
# 	50 : LowGrayLevelRunEmphasis [NUMERICAL]
# 	47 : SmallAreaLowGrayLevelEmphasis [NUMERICAL]
# 	46 : LowGrayLevelZoneEmphasis [NUMERICAL]
# 	45 : Imc1 [NUMERICAL]
# 	44 : LongRunLowGrayLevelEmphasis [NUMERICAL]
# 	41 : 10Percentile [NUMERICAL]
# 	39 : Strength [NUMERICAL]
# 	35 : Minimum [NUMERICAL]
# 	33 : LargeDependenceLowGrayLevelEmphasis [NUMERICAL]
# 	31 : Uniformity [NUMERICAL]
# 	31 : RunVariance [NUMERICAL]
# 	30 : SumEntropy [NUMERICAL]
# 	29 : InverseVariance [NUMERICAL]
# 	28 : Kurtosis [NUMERICAL]
# 	27 : SmallDependenceHighGrayLevelEmphasis [NUMERICAL]
# 	27 : Imc2 [NUMERICAL]
# 	25 : DependenceNonUniformity [NUMERICAL]
# 	24 : LongRunEmphasis [NUMERICAL]
# 	24 : GrayLevelNonUniformityNormalized [NUMERICAL]
# 	23 : DifferenceEntropy [NUMERICAL]
# 	22 : LargeAreaLowGrayLevelEmphasis [NUMERICAL]
# 	21 : SmallDependenceEmphasis [NUMERICAL]
# 	21 : GrayLevelNonUniformity [NUMERICAL]
# 	20 : RunEntropy [NUMERICAL]
# 	20 : InterquartileRange [NUMERICAL]
# 	20 : GrayLevelNonUniformity.1 [NUMERICAL]
# 	19 : ZonePercentage [NUMERICAL]
# 	19 : SmallAreaEmphasis [NUMERICAL]
# 	19 : SizeZoneNonUniformityNormalized [NUMERICAL]
# 	19 : SizeZoneNonUniformity [NUMERICAL]
# 	19 : Id [NUMERICAL]
# 	19 : DifferenceVariance [NUMERICAL]
# 	19 : DependenceNonUniformityNormalized [NUMERICAL]
# 	19 : Contrast.1 [NUMERICAL]
# 	18 : ZoneVariance [NUMERICAL]
# 	18 : JointEnergy [NUMERICAL]
# 	18 : Contrast [NUMERICAL]
# 	16 : RunLengthNonUniformityNormalized [NUMERICAL]
# 	16 : RunLengthNonUniformity [NUMERICAL]
# 	16 : DependenceVariance [NUMERICAL]
# 	15 : Range [NUMERICAL]
# 	14 : Idm [NUMERICAL]
# 	14 : Entropy [NUMERICAL]
# 	13 : ShortRunEmphasis [NUMERICAL]
# 	13 : LargeDependenceEmphasis [NUMERICAL]
# 	13 : Complexity [NUMERICAL]
# 	12 : Variance [NUMERICAL]
# 	12 : SumSquares [NUMERICAL]
# 	12 : LargeAreaEmphasis [NUMERICAL]
# 	12 : JointEntropy [NUMERICAL]
# 	12 : GrayLevelNonUniformityNormalized.1 [NUMERICAL]
# 	12 : DifferenceAverage [NUMERICAL]
# 	11 : ZoneEntropy [NUMERICAL]
# 	11 : RunPercentage [NUMERICAL]
# 	11 : MaximumProbability [NUMERICAL]
# 	10 : MeanAbsoluteDeviation [NUMERICAL]
# 	9 : ClusterProminence [NUMERICAL]
# 	8 : RobustMeanAbsoluteDeviation [NUMERICAL]
# 	8 : GrayLevelVariance.2 [NUMERICAL]
# 	8 : GrayLevelVariance.1 [NUMERICAL]
# 	8 : ClusterTendency [NUMERICAL]
# 	7 : GrayLevelVariance [NUMERICAL]
#
# Attribute in nodes with depth <= 5:
# 	327 : Idmn [NUMERICAL]
# 	324 : Idn [NUMERICAL]
# 	283 : GrayLevelNonUniformity.2 [NUMERICAL]
# 	276 : LongRunHighGrayLevelEmphasis [NUMERICAL]
# 	275 : Skewness [NUMERICAL]
# 	266 : Coarseness [NUMERICAL]
# 	247 : LargeDependenceHighGrayLevelEmphasis [NUMERICAL]
# 	237 : Busyness [NUMERICAL]
# 	222 : Correlation [NUMERICAL]
# 	217 : Median [NUMERICAL]
# 	184 : ClusterShade [NUMERICAL]
# 	183 : 90Percentile [NUMERICAL]
# 	179 : LargeAreaHighGrayLevelEmphasis [NUMERICAL]
# 	179 : JointAverage [NUMERICAL]
# 	175 : Mean [NUMERICAL]
# 	174 : SumAverage [NUMERICAL]
# 	171 : Maximum [NUMERICAL]
# 	169 : Autocorrelation [NUMERICAL]
# 	153 : SmallDependenceLowGrayLevelEmphasis [NUMERICAL]
# 	150 : SmallAreaHighGrayLevelEmphasis [NUMERICAL]
# 	149 : Energy [NUMERICAL]
# 	146 : MCC [NUMERICAL]
# 	142 : HighGrayLevelZoneEmphasis [NUMERICAL]
# 	140 : HighGrayLevelEmphasis [NUMERICAL]
# 	136 : ShortRunLowGrayLevelEmphasis [NUMERICAL]
# 	134 : TotalEnergy [NUMERICAL]
# 	133 : RootMeanSquared [NUMERICAL]
# 	129 : SmallAreaLowGrayLevelEmphasis [NUMERICAL]
# 	125 : Imc1 [NUMERICAL]
# 	125 : HighGrayLevelRunEmphasis [NUMERICAL]
# 	124 : DependenceEntropy [NUMERICAL]
# 	121 : ShortRunHighGrayLevelEmphasis [NUMERICAL]
# 	120 : Strength [NUMERICAL]
# 	120 : Minimum [NUMERICAL]
# 	118 : LowGrayLevelZoneEmphasis [NUMERICAL]
# 	118 : Kurtosis [NUMERICAL]
# 	116 : LongRunLowGrayLevelEmphasis [NUMERICAL]
# 	114 : LowGrayLevelEmphasis [NUMERICAL]
# 	110 : LowGrayLevelRunEmphasis [NUMERICAL]
# 	103 : InverseVariance [NUMERICAL]
# 	100 : Contrast.1 [NUMERICAL]
# 	99 : SumEntropy [NUMERICAL]
# 	98 : SizeZoneNonUniformity [NUMERICAL]
# 	98 : Contrast [NUMERICAL]
# 	96 : SmallDependenceEmphasis [NUMERICAL]
# 	93 : 10Percentile [NUMERICAL]
# 	88 : Imc2 [NUMERICAL]
# 	88 : GrayLevelNonUniformity [NUMERICAL]
# 	86 : DifferenceVariance [NUMERICAL]
# 	85 : SmallDependenceHighGrayLevelEmphasis [NUMERICAL]
# 	85 : SizeZoneNonUniformityNormalized [NUMERICAL]
# 	84 : RunVariance [NUMERICAL]
# 	84 : LargeDependenceLowGrayLevelEmphasis [NUMERICAL]
# 	83 : DifferenceEntropy [NUMERICAL]
# 	82 : Uniformity [NUMERICAL]
# 	82 : LargeAreaLowGrayLevelEmphasis [NUMERICAL]
# 	79 : DependenceVariance [NUMERICAL]
# 	78 : SmallAreaEmphasis [NUMERICAL]
# 	75 : GrayLevelNonUniformityNormalized [NUMERICAL]
# 	74 : MaximumProbability [NUMERICAL]
# 	74 : LongRunEmphasis [NUMERICAL]
# 	73 : RunEntropy [NUMERICAL]
# 	73 : InterquartileRange [NUMERICAL]
# 	73 : GrayLevelNonUniformity.1 [NUMERICAL]
# 	72 : Idm [NUMERICAL]
# 	72 : DifferenceAverage [NUMERICAL]
# 	71 : Complexity [NUMERICAL]
# 	70 : Range [NUMERICAL]
# 	69 : ZonePercentage [NUMERICAL]
# 	69 : DependenceNonUniformity [NUMERICAL]
# 	67 : RunLengthNonUniformityNormalized [NUMERICAL]
# 	67 : Id [NUMERICAL]
# 	66 : DependenceNonUniformityNormalized [NUMERICAL]
# 	65 : Entropy [NUMERICAL]
# 	61 : ShortRunEmphasis [NUMERICAL]
# 	59 : GrayLevelNonUniformityNormalized.1 [NUMERICAL]
# 	59 : ClusterProminence [NUMERICAL]
# 	58 : ZoneEntropy [NUMERICAL]
# 	58 : JointEnergy [NUMERICAL]
# 	56 : LargeDependenceEmphasis [NUMERICAL]
# 	55 : MeanAbsoluteDeviation [NUMERICAL]
# 	54 : RunLengthNonUniformity [NUMERICAL]
# 	54 : LargeAreaEmphasis [NUMERICAL]
# 	53 : JointEntropy [NUMERICAL]
# 	53 : ClusterTendency [NUMERICAL]
# 	50 : ZoneVariance [NUMERICAL]
# 	49 : RunPercentage [NUMERICAL]
# 	47 : RobustMeanAbsoluteDeviation [NUMERICAL]
# 	47 : GrayLevelVariance.2 [NUMERICAL]
# 	44 : Variance [NUMERICAL]
# 	42 : GrayLevelVariance.1 [NUMERICAL]
# 	40 : GrayLevelVariance [NUMERICAL]
# 	35 : SumSquares [NUMERICAL]
#
# Condition type in nodes:
# 	30993 : HigherCondition
# Condition type in nodes with depth <= 0:
# 	300 : HigherCondition
# Condition type in nodes with depth <= 1:
# 	900 : HigherCondition
# Condition type in nodes with depth <= 2:
# 	2082 : HigherCondition
# Condition type in nodes with depth <= 3:
# 	3974 : HigherCondition
# Condition type in nodes with depth <= 5:
# 	10606 : HigherCondition
# Node format: NOT_SET
#
# Training OOB:
# 	trees: 1, Out-of-bag evaluation: accuracy:0.809263 logloss:6.87485
# 	trees: 11, Out-of-bag evaluation: accuracy:0.834618 logloss:2.50882
# 	trees: 21, Out-of-bag evaluation: accuracy:0.846428 logloss:1.11047
# 	trees: 31, Out-of-bag evaluation: accuracy:0.852653 logloss:0.793455
# 	trees: 41, Out-of-bag evaluation: accuracy:0.852934 logloss:0.727778
# 	trees: 51, Out-of-bag evaluation: accuracy:0.858036 logloss:0.689303
# 	trees: 61, Out-of-bag evaluation: accuracy:0.857085 logloss:0.620618
# 	trees: 71, Out-of-bag evaluation: accuracy:0.857576 logloss:0.587295
# 	trees: 82, Out-of-bag evaluation: accuracy:0.860567 logloss:0.554443
# 	trees: 92, Out-of-bag evaluation: accuracy:0.857647 logloss:0.524078
# 	trees: 102, Out-of-bag evaluation: accuracy:0.859968 logloss:0.491821
# 	trees: 112, Out-of-bag evaluation: accuracy:0.861798 logloss:0.49151
# 	trees: 122, Out-of-bag evaluation: accuracy:0.861728 logloss:0.491771
# 	trees: 132, Out-of-bag evaluation: accuracy:0.860848 logloss:0.458401
# 	trees: 142, Out-of-bag evaluation: accuracy:0.860108 logloss:0.460126
# 	trees: 152, Out-of-bag evaluation: accuracy:0.859158 logloss:0.460498
# 	trees: 162, Out-of-bag evaluation: accuracy:0.862149 logloss:0.462406
# 	trees: 172, Out-of-bag evaluation: accuracy:0.86412 logloss:0.463567
# 	trees: 182, Out-of-bag evaluation: accuracy:0.863099 logloss:0.462871
# 	trees: 192, Out-of-bag evaluation: accuracy:0.86405 logloss:0.462778
# 	trees: 202, Out-of-bag evaluation: accuracy:0.863909 logloss:0.463508
# 	trees: 212, Out-of-bag evaluation: accuracy:0.86493 logloss:0.463065
# 	trees: 222, Out-of-bag evaluation: accuracy:0.86486 logloss:0.431797
# 	trees: 232, Out-of-bag evaluation: accuracy:0.86486 logloss:0.430977
# 	trees: 242, Out-of-bag evaluation: accuracy:0.863839 logloss:0.430456
# 	trees: 252, Out-of-bag evaluation: accuracy:0.862889 logloss:0.430675
# 	trees: 262, Out-of-bag evaluation: accuracy:0.862889 logloss:0.429761
# 	trees: 272, Out-of-bag evaluation: accuracy:0.863909 logloss:0.397369
# 	trees: 282, Out-of-bag evaluation: accuracy:0.86493 logloss:0.397733
# 	trees: 292, Out-of-bag evaluation: accuracy:0.86412 logloss:0.39775
# 	trees: 300, Out-of-bag evaluation: accuracy:0.86588 logloss:0.396901

# %%
# Model features
model.make_inspector().features()
# Out:
# ["10Percentile" (1; #0),
#  "90Percentile" (1; #1),
#  "Autocorrelation" (1; #2),
#  "Busyness" (1; #3),
#  "ClusterProminence" (1; #4),
#  "ClusterShade" (1; #5),
#  "ClusterTendency" (1; #6),
#  "Coarseness" (1; #7),
#  "Complexity" (1; #8),
#  "Contrast" (1; #9),
#  "Contrast.1" (1; #10),
#  "Correlation" (1; #11),
#  "DependenceEntropy" (1; #12),
#  "DependenceNonUniformity" (1; #13),
#  "DependenceNonUniformityNormalized" (1; #14),
#  "DependenceVariance" (1; #15),
#  "DifferenceAverage" (1; #16),
#  "DifferenceEntropy" (1; #17),
#  "DifferenceVariance" (1; #18),
#  "Energy" (1; #19),
#  "Entropy" (1; #20),
#  "GrayLevelNonUniformity" (1; #21),
#  "GrayLevelNonUniformity.1" (1; #22),
#  "GrayLevelNonUniformity.2" (1; #23),
#  "GrayLevelNonUniformityNormalized" (1; #24),
#  "GrayLevelNonUniformityNormalized.1" (1; #25),
#  "GrayLevelVariance" (1; #26),
#  "GrayLevelVariance.1" (1; #27),
#  "GrayLevelVariance.2" (1; #28),
#  "HighGrayLevelEmphasis" (1; #29),
#  "HighGrayLevelRunEmphasis" (1; #30),
#  "HighGrayLevelZoneEmphasis" (1; #31),
#  "Id" (1; #32),
#  "Idm" (1; #33),
#  "Idmn" (1; #34),
#  "Idn" (1; #35),
#  "Imc1" (1; #36),
#  "Imc2" (1; #37),
#  "InterquartileRange" (1; #38),
#  "InverseVariance" (1; #39),
#  "JointAverage" (1; #40),
#  "JointEnergy" (1; #41),
#  "JointEntropy" (1; #42),
#  "Kurtosis" (1; #43),
#  "LargeAreaEmphasis" (1; #44),
#  "LargeAreaHighGrayLevelEmphasis" (1; #45),
#  "LargeAreaLowGrayLevelEmphasis" (1; #46),
#  "LargeDependenceEmphasis" (1; #47),
#  "LargeDependenceHighGrayLevelEmphasis" (1; #48),
#  "LargeDependenceLowGrayLevelEmphasis" (1; #49),
#  "LongRunEmphasis" (1; #50),
#  "LongRunHighGrayLevelEmphasis" (1; #51),
#  "LongRunLowGrayLevelEmphasis" (1; #52),
#  "LowGrayLevelEmphasis" (1; #53),
#  "LowGrayLevelRunEmphasis" (1; #54),
#  "LowGrayLevelZoneEmphasis" (1; #55),
#  "MCC" (1; #56),
#  "Maximum" (1; #57),
#  "MaximumProbability" (1; #58),
#  "Mean" (1; #59),
#  "MeanAbsoluteDeviation" (1; #60),
#  "Median" (1; #61),
#  "Minimum" (1; #62),
#  "Range" (1; #63),
#  "RobustMeanAbsoluteDeviation" (1; #64),
#  "RootMeanSquared" (1; #65),
#  "RunEntropy" (1; #66),
#  "RunLengthNonUniformity" (1; #67),
#  "RunLengthNonUniformityNormalized" (1; #68),
#  "RunPercentage" (1; #69),
#  "RunVariance" (1; #70),
#  "ShortRunEmphasis" (1; #71),
#  "ShortRunHighGrayLevelEmphasis" (1; #72),
#  "ShortRunLowGrayLevelEmphasis" (1; #73),
#  "SizeZoneNonUniformity" (1; #74),
#  "SizeZoneNonUniformityNormalized" (1; #75),
#  "Skewness" (1; #76),
#  "SmallAreaEmphasis" (1; #77),
#  "SmallAreaHighGrayLevelEmphasis" (1; #78),
#  "SmallAreaLowGrayLevelEmphasis" (1; #79),
#  "SmallDependenceEmphasis" (1; #80),
#  "SmallDependenceHighGrayLevelEmphasis" (1; #81),
#  "SmallDependenceLowGrayLevelEmphasis" (1; #82),
#  "Strength" (1; #83),
#  "SumAverage" (1; #84),
#  "SumEntropy" (1; #85),
#  "SumSquares" (1; #86),
#  "TotalEnergy" (1; #87),
#  "Uniformity" (1; #88),
#  "Variance" (1; #89),
#  "ZoneEntropy" (1; #90),
#  "ZonePercentage" (1; #91),
#  "ZoneVariance" (1; #92)]

# %%
# Feature importance
model.make_inspector().variable_importances()
# Out:
# {'INV_MEAN_MIN_DEPTH': [("LongRunHighGrayLevelEmphasis" (1; #51),
#    0.1319427904232496),
#   ("LargeDependenceHighGrayLevelEmphasis" (1; #48), 0.12398003404852684),
#   ("Coarseness" (1; #7), 0.11993751523971566),
#   ("GrayLevelNonUniformity.2" (1; #23), 0.11902729383919709),
#   ("SumAverage" (1; #84), 0.11810420567497926),
#   ("90Percentile" (1; #1), 0.11802315674613459),
#   ("TotalEnergy" (1; #87), 0.11785444103779869),
#   ("Mean" (1; #59), 0.11772292532144626),
#   ("Autocorrelation" (1; #2), 0.1176558867545406),
#   ("Busyness" (1; #3), 0.11727970223200354),
#   ("LargeAreaHighGrayLevelEmphasis" (1; #45), 0.1172270012651868),
#   ("Median" (1; #61), 0.11717773533192993),
#   ("HighGrayLevelZoneEmphasis" (1; #31), 0.11664763613368018),
#   ("JointAverage" (1; #40), 0.11591228254132797),
#   ("Energy" (1; #19), 0.1156879240566852),
#   ("HighGrayLevelEmphasis" (1; #29), 0.11553486528817443),
#   ("Idn" (1; #35), 0.11472971548011793),
#   ("Idmn" (1; #34), 0.1146115917648029),
#   ("SmallDependenceLowGrayLevelEmphasis" (1; #82), 0.11424931428655344),
#   ("HighGrayLevelRunEmphasis" (1; #30), 0.1135400189932177),
#   ("ShortRunHighGrayLevelEmphasis" (1; #72), 0.11280909507715488),
#   ("RootMeanSquared" (1; #65), 0.11276552421984805),
#   ("Maximum" (1; #57), 0.11199023311164533),
#   ("Correlation" (1; #11), 0.111846892824024),
#   ("Skewness" (1; #76), 0.11147309556881482),
#   ("ShortRunLowGrayLevelEmphasis" (1; #73), 0.11122820221910315),
#   ("SmallAreaHighGrayLevelEmphasis" (1; #78), 0.11095985560413205),
#   ("LowGrayLevelEmphasis" (1; #53), 0.11060095589884843),
#   ("10Percentile" (1; #0), 0.11043864441740181),
#   ("SmallAreaLowGrayLevelEmphasis" (1; #79), 0.11014440026764485),
#   ("LowGrayLevelRunEmphasis" (1; #54), 0.10992228536768606),
#   ("LowGrayLevelZoneEmphasis" (1; #55), 0.10990039429920065),
#   ("LongRunLowGrayLevelEmphasis" (1; #52), 0.10970965918584934),
#   ("ClusterShade" (1; #5), 0.10930826315057664),
#   ("Minimum" (1; #62), 0.1089913321571293),
#   ("LargeDependenceLowGrayLevelEmphasis" (1; #49), 0.10889868953253279),
#   ("Imc1" (1; #36), 0.10888654953932546),
#   ("InverseVariance" (1; #39), 0.10886040296896486),
#   ("DependenceEntropy" (1; #12), 0.10846258300614785),
#   ("MCC" (1; #56), 0.10840429996915027),
#   ("Strength" (1; #83), 0.10828000411281535),
#   ("DependenceNonUniformity" (1; #13), 0.10796879180580884),
#   ("SmallDependenceEmphasis" (1; #80), 0.10782270051185168),
#   ("Imc2" (1; #37), 0.10778507653293917),
#   ("RunVariance" (1; #70), 0.10772909155979189),
#   ("SmallDependenceHighGrayLevelEmphasis" (1; #81), 0.1077212088639637),
#   ("SizeZoneNonUniformity" (1; #74), 0.10760927482844486),
#   ("SizeZoneNonUniformityNormalized" (1; #75), 0.10759731121575593),
#   ("DependenceVariance" (1; #15), 0.1071382976817353),
#   ("SumEntropy" (1; #85), 0.10705660604261794),
#   ("LongRunEmphasis" (1; #50), 0.10705355084148813),
#   ("Contrast" (1; #9), 0.10692129560829508),
#   ("Id" (1; #32), 0.10691252458667694),
#   ("Idm" (1; #33), 0.10690691991973532),
#   ("LargeAreaLowGrayLevelEmphasis" (1; #46), 0.10688053826565369),
#   ("DependenceNonUniformityNormalized" (1; #14), 0.10686997292109598),
#   ("DifferenceEntropy" (1; #17), 0.10686220020853816),
#   ("GrayLevelNonUniformity" (1; #21), 0.10685718671890392),
#   ("Contrast.1" (1; #10), 0.10681245006687598),
#   ("SmallAreaEmphasis" (1; #77), 0.106792694964892),
#   ("ZonePercentage" (1; #91), 0.10669644838124075),
#   ("RunLengthNonUniformityNormalized" (1; #68), 0.1064006903598364),
#   ("RunEntropy" (1; #66), 0.10623002459192642),
#   ("Kurtosis" (1; #43), 0.10622471263624549),
#   ("Range" (1; #63), 0.10616734465243342),
#   ("RunLengthNonUniformity" (1; #67), 0.10609751838738653),
#   ("Uniformity" (1; #88), 0.10606270505230606),
#   ("DifferenceAverage" (1; #16), 0.10599541246110526),
#   ("ShortRunEmphasis" (1; #71), 0.1059864846555458),
#   ("GrayLevelNonUniformityNormalized" (1; #24), 0.10596679671963811),
#   ("MaximumProbability" (1; #58), 0.1059608672644359),
#   ("GrayLevelNonUniformity.1" (1; #22), 0.10595263320387968),
#   ("LargeDependenceEmphasis" (1; #47), 0.10591355823468813),
#   ("DifferenceVariance" (1; #18), 0.10589926036947404),
#   ("RunPercentage" (1; #69), 0.10575874047100473),
#   ("Complexity" (1; #8), 0.10572340961118228),
#   ("LargeAreaEmphasis" (1; #44), 0.10565435707583959),
#   ("ZoneVariance" (1; #92), 0.10561592757020166),
#   ("SumSquares" (1; #86), 0.10558197335265944),
#   ("ClusterProminence" (1; #4), 0.105579587736128),
#   ("ClusterTendency" (1; #6), 0.10556312960230098),
#   ("InterquartileRange" (1; #38), 0.10554042618785192),
#   ("ZoneEntropy" (1; #90), 0.10552801658392509),
#   ("GrayLevelVariance.2" (1; #28), 0.10551175426189247),
#   ("Entropy" (1; #20), 0.10549252690410245),
#   ("Variance" (1; #89), 0.10536827687997606),
#   ("GrayLevelNonUniformityNormalized.1" (1; #25), 0.10533913332436291),
#   ("MeanAbsoluteDeviation" (1; #60), 0.10533620909284787),
#   ("GrayLevelVariance.1" (1; #27), 0.10524794274988149),
#   ("JointEnergy" (1; #41), 0.10524273510670451),
#   ("JointEntropy" (1; #42), 0.10523838693726711),
#   ("RobustMeanAbsoluteDeviation" (1; #64), 0.1052369066661724),
#   ("GrayLevelVariance" (1; #26), 0.1051880403042085)],
#  'SUM_SCORE': [("LongRunHighGrayLevelEmphasis" (1; #51), 95664.48562506428),
#   ("TotalEnergy" (1; #87), 64409.44128223545),
#   ("HighGrayLevelZoneEmphasis" (1; #31), 62183.26386831079),
#   ("SumAverage" (1; #84), 55557.141492069066),
#   ("Autocorrelation" (1; #2), 55296.67241260267),
#   ("90Percentile" (1; #1), 53109.60874003605),
#   ("HighGrayLevelEmphasis" (1; #29), 50326.78766417796),
#   ("Energy" (1; #19), 47837.72961488956),
#   ("Mean" (1; #59), 45805.175590019564),
#   ("JointAverage" (1; #40), 43972.118424082444),
#   ("LargeDependenceHighGrayLevelEmphasis" (1; #48), 42122.236666080586),
#   ("HighGrayLevelRunEmphasis" (1; #30), 41629.2110466265),
#   ("Idn" (1; #35), 35237.877748896615),
#   ("Idmn" (1; #34), 34327.858987452004),
#   ("ShortRunHighGrayLevelEmphasis" (1; #72), 33285.41709586514),
#   ("RootMeanSquared" (1; #65), 32808.03418153692),
#   ("Coarseness" (1; #7), 29359.36118185817),
#   ("GrayLevelNonUniformity.2" (1; #23), 28308.741073167657),
#   ("Busyness" (1; #3), 26970.22856521301),
#   ("Maximum" (1; #57), 26291.088225482734),
#   ("Median" (1; #61), 25133.799584398126),
#   ("LargeAreaHighGrayLevelEmphasis" (1; #45), 24688.255384342934),
#   ("SmallAreaHighGrayLevelEmphasis" (1; #78), 22691.57153165703),
#   ("ShortRunLowGrayLevelEmphasis" (1; #73), 21745.13187385849),
#   ("SmallDependenceLowGrayLevelEmphasis" (1; #82), 21049.841784908283),
#   ("LowGrayLevelZoneEmphasis" (1; #55), 21000.10696356821),
#   ("SmallAreaLowGrayLevelEmphasis" (1; #79), 19656.47860377452),
#   ("LowGrayLevelEmphasis" (1; #53), 17802.942219315508),
#   ("Correlation" (1; #11), 16220.105702250305),
#   ("Skewness" (1; #76), 15216.990133168443),
#   ("LowGrayLevelRunEmphasis" (1; #54), 14779.94332670712),
#   ("Minimum" (1; #62), 12760.732316197236),
#   ("10Percentile" (1; #0), 12317.405836841413),
#   ("LongRunLowGrayLevelEmphasis" (1; #52), 11964.479840133808),
#   ("ClusterShade" (1; #5), 11956.732032902752),
#   ("Imc1" (1; #36), 11091.044186522906),
#   ("InverseVariance" (1; #39), 10064.918600648834),
#   ("LargeDependenceLowGrayLevelEmphasis" (1; #49), 10042.466850067765),
#   ("DependenceEntropy" (1; #12), 10013.147858201379),
#   ("SmallDependenceHighGrayLevelEmphasis" (1; #81), 9798.506929239276),
#   ("Strength" (1; #83), 9488.831508899371),
#   ("MCC" (1; #56), 9078.97866190241),
#   ("Imc2" (1; #37), 9059.942473477688),
#   ("SumEntropy" (1; #85), 8583.871342882429),
#   ("SizeZoneNonUniformity" (1; #74), 8397.188209553813),
#   ("SizeZoneNonUniformityNormalized" (1; #75), 8069.953400419054),
#   ("Contrast" (1; #9), 7828.453785802417),
#   ("SmallDependenceEmphasis" (1; #80), 7702.076630324507),
#   ("RunVariance" (1; #70), 7666.636547704797),
#   ("Contrast.1" (1; #10), 7381.358782219636),
#   ("SmallAreaEmphasis" (1; #77), 7371.788820296826),
#   ("DependenceNonUniformity" (1; #13), 7086.560379367401),
#   ("DependenceVariance" (1; #15), 7051.341875954181),
#   ("Idm" (1; #33), 7038.8892071121245),
#   ("LongRunEmphasis" (1; #50), 6664.367920955478),
#   ("LargeAreaLowGrayLevelEmphasis" (1; #46), 6571.571376639458),
#   ("Id" (1; #32), 6567.198013949223),
#   ("DifferenceEntropy" (1; #17), 6191.134452209793),
#   ("Range" (1; #63), 6111.500456552439),
#   ("Kurtosis" (1; #43), 6094.106619517239),
#   ("DependenceNonUniformityNormalized" (1; #14), 6060.106760330332),
#   ("DifferenceVariance" (1; #18), 5985.100658780023),
#   ("RunEntropy" (1; #66), 5950.488171250327),
#   ("ZonePercentage" (1; #91), 5872.577635711244),
#   ("DifferenceAverage" (1; #16), 5632.12728204542),
#   ("GrayLevelNonUniformity" (1; #21), 5587.451174925516),
#   ("Complexity" (1; #8), 5476.503661408339),
#   ("RunLengthNonUniformityNormalized" (1; #68), 5463.960467322789),
#   ("ShortRunEmphasis" (1; #71), 5338.5663801545115),
#   ("GrayLevelNonUniformity.1" (1; #22), 5187.32402730837),
#   ("Uniformity" (1; #88), 5121.315075426326),
#   ("InterquartileRange" (1; #38), 5103.961142090452),
#   ("RunLengthNonUniformity" (1; #67), 4938.898847547058),
#   ("RunPercentage" (1; #69), 4762.92551996656),
#   ("LargeDependenceEmphasis" (1; #47), 4494.786912231058),
#   ("MaximumProbability" (1; #58), 4488.651310968749),
#   ("Entropy" (1; #20), 4436.208804852513),
#   ("GrayLevelNonUniformityNormalized" (1; #24), 4300.744095028131),
#   ("ClusterTendency" (1; #6), 4286.221091472765),
#   ("ZoneEntropy" (1; #90), 4267.11359149324),
#   ("SumSquares" (1; #86), 4187.213458857202),
#   ("GrayLevelNonUniformityNormalized.1" (1; #25), 4185.687433564989),
#   ("ZoneVariance" (1; #92), 4059.2295311445473),
#   ("LargeAreaEmphasis" (1; #44), 3980.3294971771743),
#   ("MeanAbsoluteDeviation" (1; #60), 3942.307019099134),
#   ("JointEnergy" (1; #41), 3896.564151012143),
#   ("Variance" (1; #89), 3785.7620854948213),
#   ("ClusterProminence" (1; #4), 3780.944915931742),
#   ("GrayLevelVariance.2" (1; #28), 3775.8661055842786),
#   ("GrayLevelVariance" (1; #26), 3538.721765795124),
#   ("GrayLevelVariance.1" (1; #27), 3522.997886243106),
#   ("RobustMeanAbsoluteDeviation" (1; #64), 3412.225751361189),
#   ("JointEntropy" (1; #42), 3382.8711047197708)],
#  'NUM_AS_ROOT': [("LongRunHighGrayLevelEmphasis" (1; #51), 31.0),
#   ("HighGrayLevelZoneEmphasis" (1; #31), 25.0),
#   ("TotalEnergy" (1; #87), 25.0),
#   ("SumAverage" (1; #84), 20.0),
#   ("90Percentile" (1; #1), 19.0),
#   ("Autocorrelation" (1; #2), 19.0),
#   ("HighGrayLevelEmphasis" (1; #29), 19.0),
#   ("Energy" (1; #19), 18.0),
#   ("HighGrayLevelRunEmphasis" (1; #30), 16.0),
#   ("JointAverage" (1; #40), 15.0),
#   ("Mean" (1; #59), 14.0),
#   ("ShortRunHighGrayLevelEmphasis" (1; #72), 11.0),
#   ("RootMeanSquared" (1; #65), 10.0),
#   ("LowGrayLevelZoneEmphasis" (1; #55), 6.0),
#   ("ShortRunLowGrayLevelEmphasis" (1; #73), 6.0),
#   ("SmallAreaHighGrayLevelEmphasis" (1; #78), 6.0),
#   ("SmallAreaLowGrayLevelEmphasis" (1; #79), 6.0),
#   ("Maximum" (1; #57), 5.0),
#   ("LowGrayLevelEmphasis" (1; #53), 4.0),
#   ("Minimum" (1; #62), 4.0),
#   ("LowGrayLevelRunEmphasis" (1; #54), 3.0),
#   ("Median" (1; #61), 3.0),
#   ("Correlation" (1; #11), 2.0),
#   ("GrayLevelNonUniformity" (1; #21), 2.0),
#   ("LongRunLowGrayLevelEmphasis" (1; #52), 2.0),
#   ("SmallDependenceLowGrayLevelEmphasis" (1; #82), 2.0),
#   ("10Percentile" (1; #0), 1.0),
#   ("Busyness" (1; #3), 1.0),
#   ("Coarseness" (1; #7), 1.0),
#   ("LargeAreaHighGrayLevelEmphasis" (1; #45), 1.0),
#   ("LargeDependenceLowGrayLevelEmphasis" (1; #49), 1.0),
#   ("SmallDependenceHighGrayLevelEmphasis" (1; #81), 1.0),
#   ("Uniformity" (1; #88), 1.0)],
#  'NUM_NODES': [("Idn" (1; #35), 1092.0),
#   ("Idmn" (1; #34), 1075.0),
#   ("Skewness" (1; #76), 662.0),
#   ("Coarseness" (1; #7), 631.0),
#   ("GrayLevelNonUniformity.2" (1; #23), 607.0),
#   ("Busyness" (1; #3), 606.0),
#   ("LargeDependenceHighGrayLevelEmphasis" (1; #48), 545.0),
#   ("Correlation" (1; #11), 533.0),
#   ("ClusterShade" (1; #5), 528.0),
#   ("LongRunHighGrayLevelEmphasis" (1; #51), 523.0),
#   ("Maximum" (1; #57), 510.0),
#   ("Median" (1; #61), 457.0),
#   ("MCC" (1; #56), 436.0),
#   ("LargeAreaHighGrayLevelEmphasis" (1; #45), 419.0),
#   ("SmallDependenceLowGrayLevelEmphasis" (1; #82), 411.0),
#   ("SmallAreaHighGrayLevelEmphasis" (1; #78), 409.0),
#   ("90Percentile" (1; #1), 405.0),
#   ("DependenceEntropy" (1; #12), 399.0),
#   ("Kurtosis" (1; #43), 383.0),
#   ("SmallAreaLowGrayLevelEmphasis" (1; #79), 383.0),
#   ("HighGrayLevelZoneEmphasis" (1; #31), 378.0),
#   ("Strength" (1; #83), 370.0),
#   ("Contrast.1" (1; #10), 365.0),
#   ("Minimum" (1; #62), 363.0),
#   ("Imc1" (1; #36), 356.0),
#   ("JointAverage" (1; #40), 352.0),
#   ("Contrast" (1; #9), 350.0),
#   ("SumAverage" (1; #84), 349.0),
#   ("Mean" (1; #59), 343.0),
#   ("SizeZoneNonUniformityNormalized" (1; #75), 342.0),
#   ("Autocorrelation" (1; #2), 340.0),
#   ("Energy" (1; #19), 331.0),
#   ("SmallAreaEmphasis" (1; #77), 329.0),
#   ("SizeZoneNonUniformity" (1; #74), 325.0),
#   ("HighGrayLevelEmphasis" (1; #29), 322.0),
#   ("LongRunLowGrayLevelEmphasis" (1; #52), 322.0),
#   ("LowGrayLevelZoneEmphasis" (1; #55), 322.0),
#   ("LowGrayLevelRunEmphasis" (1; #54), 321.0),
#   ("SumEntropy" (1; #85), 320.0),
#   ("ShortRunHighGrayLevelEmphasis" (1; #72), 319.0),
#   ("10Percentile" (1; #0), 318.0),
#   ("Imc2" (1; #37), 318.0),
#   ("Range" (1; #63), 315.0),
#   ("DifferenceVariance" (1; #18), 314.0),
#   ("ShortRunLowGrayLevelEmphasis" (1; #73), 313.0),
#   ("InverseVariance" (1; #39), 312.0),
#   ("InterquartileRange" (1; #38), 309.0),
#   ("LowGrayLevelEmphasis" (1; #53), 304.0),
#   ("DependenceVariance" (1; #15), 297.0),
#   ("LargeDependenceLowGrayLevelEmphasis" (1; #49), 295.0),
#   ("TotalEnergy" (1; #87), 295.0),
#   ("RootMeanSquared" (1; #65), 294.0),
#   ("RunVariance" (1; #70), 286.0),
#   ("HighGrayLevelRunEmphasis" (1; #30), 284.0),
#   ("DifferenceEntropy" (1; #17), 282.0),
#   ("LargeAreaLowGrayLevelEmphasis" (1; #46), 279.0),
#   ("SmallDependenceHighGrayLevelEmphasis" (1; #81), 277.0),
#   ("SmallDependenceEmphasis" (1; #80), 271.0),
#   ("Idm" (1; #33), 268.0),
#   ("Uniformity" (1; #88), 266.0),
#   ("Complexity" (1; #8), 265.0),
#   ("DifferenceAverage" (1; #16), 250.0),
#   ("DependenceNonUniformity" (1; #13), 249.0),
#   ("GrayLevelNonUniformity" (1; #21), 249.0),
#   ("MaximumProbability" (1; #58), 247.0),
#   ("LongRunEmphasis" (1; #50), 241.0),
#   ("GrayLevelNonUniformity.1" (1; #22), 240.0),
#   ("GrayLevelNonUniformityNormalized.1" (1; #25), 240.0),
#   ("DependenceNonUniformityNormalized" (1; #14), 238.0),
#   ("RunEntropy" (1; #66), 237.0),
#   ("GrayLevelVariance.2" (1; #28), 234.0),
#   ("RobustMeanAbsoluteDeviation" (1; #64), 231.0),
#   ("GrayLevelNonUniformityNormalized" (1; #24), 227.0),
#   ("Id" (1; #32), 226.0),
#   ("ZoneEntropy" (1; #90), 225.0),
#   ("ZonePercentage" (1; #91), 221.0),
#   ("JointEnergy" (1; #41), 218.0),
#   ("LargeDependenceEmphasis" (1; #47), 218.0),
#   ("MeanAbsoluteDeviation" (1; #60), 215.0),
#   ("ClusterProminence" (1; #4), 214.0),
#   ("ClusterTendency" (1; #6), 214.0),
#   ("SumSquares" (1; #86), 211.0),
#   ("Entropy" (1; #20), 205.0),
#   ("RunLengthNonUniformityNormalized" (1; #68), 205.0),
#   ("Variance" (1; #89), 205.0),
#   ("ZoneVariance" (1; #92), 203.0),
#   ("LargeAreaEmphasis" (1; #44), 198.0),
#   ("ShortRunEmphasis" (1; #71), 198.0),
#   ("RunLengthNonUniformity" (1; #67), 196.0),
#   ("GrayLevelVariance" (1; #26), 192.0),
#   ("RunPercentage" (1; #69), 189.0),
#   ("GrayLevelVariance.1" (1; #27), 183.0),
#   ("JointEntropy" (1; #42), 179.0)]}

# %%
# Model self evaluation
model.make_inspector().evaluation()
# Out:
# Evaluation(num_examples=7617, accuracy=0.8658799684398776, loss=0.39690050352164197, rmse=None, ndcg=None, aucs=None, auuc=None, qini=None)

# %%
logs = model.make_inspector().training_logs()

plt.figure(figsize=(12, 4))
plt.subplot(1, 2, 1)
plt.plot([log.num_trees for log in logs], [log.evaluation.accuracy for log in logs])
plt.xlabel("Number of trees")
plt.ylabel("Accuracy (out-of-bag)")
plt.subplot(1, 2, 2)
plt.plot([log.num_trees for log in logs], [log.evaluation.loss for log in logs])
plt.xlabel("Number of trees")
plt.ylabel("Logloss (out-of-bag)")
plt.show()

# %% [markdown]
# Calculate the score of our hold-out validation dataset

# %%
predictions = model.predict(val_ds)
y_true      = validation_data["label"]

from sklearn.metrics import roc_auc_score
ROC_AUC = roc_auc_score(y_true, predictions)
print("The ROC AUC score is %.5f" % ROC_AUC )
# Out:
# 1/2 [==============>...............] - ETA: 0s
# 2/2 [==============================] - 0s 5ms/step
# The ROC AUC score is 0.99774

# %%
# Compute binary classification metrics with sklearn
import numpy as np
from sklearn.metrics import (
    accuracy_score,
    precision_score,
    recall_score,
    f1_score,
    roc_auc_score,
    average_precision_score,
    confusion_matrix,
    classification_report,
    matthews_corrcoef,
    log_loss,
    brier_score_loss,
)

# Get predictions (probabilities or class labels)
preds = model.predict(test_ds)
# If model outputs probabilities, convert to labels by threshold 0.5
if preds.ndim == 2:
    # For TFDF classification, preds may be class probabilities with shape (N, 2)
    if preds.shape[1] == 2:
        pos_probs = preds[:, 1]
    else:
        # If single-probability column (positive class)
        pos_probs = preds[:, -1]
    y_pred = (pos_probs >= 0.5).astype(int)
else:
    # Already class labels
    y_pred = preds.astype(int)
    pos_probs = None

# Ground truth labels (must be 0/1 integers)
y_true = test_data["label"].astype(int).to_numpy()

# Core metrics
metrics = {}
metrics["accuracy"] = accuracy_score(y_true, y_pred)
metrics["precision"] = precision_score(y_true, y_pred, zero_division=0)
metrics["recall"] = recall_score(y_true, y_pred, zero_division=0)
metrics["f1"] = f1_score(y_true, y_pred, zero_division=0)
metrics["mcc"] = matthews_corrcoef(y_true, y_pred)

# Probabilistic metrics (only if we have probabilities)
if pos_probs is not None:
    metrics["roc_auc"] = roc_auc_score(y_true, pos_probs)
    metrics["pr_auc"] = average_precision_score(y_true, pos_probs)
    metrics["log_loss"] = log_loss(y_true, pos_probs, labels=[0,1])
    metrics["brier_score"] = brier_score_loss(y_true, pos_probs)

# Confusion matrix and detailed report
cm = confusion_matrix(y_true, y_pred, labels=[0,1])
report = classification_report(y_true, y_pred, digits=4)

print("Sklearn binary metrics:")
for k, v in metrics.items():
    print(f"{k}: {v:.4f}")
print("\nConfusion matrix:\n", cm)
print("\nClassification report:\n", report)
# Out:
# 1/3 [=========>....................] - ETA: 0s
# 3/3 [==============================] - 0s 16ms/step
# Sklearn binary metrics:
# accuracy: 0.9658
# precision: 0.9209
# recall: 0.7181
# f1: 0.8069
# mcc: 0.7959
# roc_auc: 0.9738
# pr_auc: 0.8830
# log_loss: 0.1057
# brier_score: 0.0266
#
# Confusion matrix:
#  [[2042   14]
#  [  64  163]]
#
# Classification report:
#                precision    recall  f1-score   support
#
#            0     0.9696    0.9932    0.9813      2056
#            1     0.9209    0.7181    0.8069       227
#
#     accuracy                         0.9658      2283
#    macro avg     0.9453    0.8556    0.8941      2283
# weighted avg     0.9648    0.9658    0.9639      2283
