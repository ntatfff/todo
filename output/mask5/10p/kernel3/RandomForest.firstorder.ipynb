# %%
# Import packages and modules
import numpy  as np
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow_decision_forests as tfdf

from sklearn.model_selection import train_test_split
# Out:
# 2026-09-12 10:36:47.002075: I tensorflow/core/util/port.cc:113] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2026-09-12 10:36:47.378688: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2026-09-12 10:36:52.010634: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
# Check the version of TensorFlow Decision Forests
print("Found TensorFlow Decision Forests v" + tfdf.__version__)
# Out:
# Found TensorFlow Decision Forests v1.9.1

# %%
datasetPath = "dataset/10p/all/kernel3/"

# %%
# Parameters
datasetPath = "dataset/mask5/10p/firstorder/kernel3/"

# %%
# train/validation/test = 70/10/20
train_data = pd.read_csv(f"{datasetPath}dataset.train.csv")
validation_data = pd.read_csv(f"{datasetPath}dataset.validation.csv")
test_data = pd.read_csv(f"{datasetPath}dataset.test.csv")

# %%
from sklearn.utils.class_weight import compute_class_weight

# tinh class weight tren tap train
classes = np.array([0, 1])
weights = compute_class_weight(class_weight="balanced", classes=classes, y=train_data["label"])
class_weight = {0: weights[0], 1: weights[1]}

# gan sample_weight cho tung dong
train_data["sample_weight"] = train_data["label"].map(class_weight)
validation_data["sample_weight"] = validation_data["label"].map(class_weight)
test_data["sample_weight"] = test_data["label"].map(class_weight)

# Convert the dataset into a TensorFlow dataset.
train_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    train_data, label="label", weight="sample_weight"
)         
val_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    validation_data, label="label", weight="sample_weight"
)
test_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    test_data, label="label", weight="sample_weight"
)
# Out:
# 2026-09-12 10:37:05.758085: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:984] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2026-09-12 10:37:05.759837: W tensorflow/core/common_runtime/gpu/gpu_device.cc:2251] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...

# %%
import keras

# %%
# %%time

# Train a Random Forest model.
model = tfdf.keras.RandomForestModel()

# Add evaluation metrics
model.compile(
    metrics=["accuracy"]
)
model.fit(x=train_ds)

# # Train a Gradient Boosted Trees model.
# model = tfdf.keras.GradientBoostedTreesModel(num_trees=1500)
# model.fit(train_ds)
# Out:
# Use /tmp/tmpr4aoo_gw as temporary training directory
# Reading training dataset...
# Training dataset read in 0:00:02.642880. Found 7617 examples.
# Training model...
# Model trained in 0:00:00.607902
# Compiling model...
# [INFO 26-09-12 10:37:09.0580 UTC kernel.cc:1233] Loading model from path /tmp/tmpr4aoo_gw/model/ with prefix 83240fdef44444ba
# [INFO 26-09-12 10:37:09.1678 UTC decision_forest.cc:734] Model loaded with 300 root(s), 82034 node(s), and 18 input feature(s).
# [INFO 26-09-12 10:37:09.1678 UTC abstract_model.cc:1362] Engine "RandomForestOptPred" built
# [INFO 26-09-12 10:37:09.1678 UTC kernel.cc:1061] Use fast generic engine
# Model compiled.
# CPU times: user 10.2 s, sys: 135 ms, total: 10.4 s
# Wall time: 6.3 s

# %%
# Evaluate the model
evaluate = model.evaluate(val_ds, return_dict=True)
print()

for name, value in evaluate.items():
    print(f"{name}: {value:.4f}")
# Out:
# WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 1/2 [==============>...............] - ETA: 3s - loss: 0.0000e+00 - accuracy: 0.9920
# 2/2 [==============================] - 3s 10ms/step - loss: 0.0000e+00 - accuracy: 0.9926
# loss: 0.0000
# accuracy: 0.9926

# %%
# Model Summary
model.summary()
# Out:
# Model: "random_forest_model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
# =================================================================
# Total params: 1 (1.00 Byte)
# Trainable params: 0 (0.00 Byte)
# Non-trainable params: 1 (1.00 Byte)
# _________________________________________________________________
# Type: "RANDOM_FOREST"
# Task: CLASSIFICATION
# Label: "__LABEL"
#
# Input Features (18):
# 	10Percentile
# 	90Percentile
# 	Energy
# 	Entropy
# 	InterquartileRange
# 	Kurtosis
# 	Maximum
# 	Mean
# 	MeanAbsoluteDeviation
# 	Median
# 	Minimum
# 	Range
# 	RobustMeanAbsoluteDeviation
# 	RootMeanSquared
# 	Skewness
# 	TotalEnergy
# 	Uniformity
# 	Variance
#
# Trained with weights
#
# Variable Importance: INV_MEAN_MIN_DEPTH:
#     1.                      "Median"  0.154897 ################
#     2.                 "TotalEnergy"  0.150294 ##############
#     3.                        "Mean"  0.145784 ############
#     4.                "90Percentile"  0.141067 ###########
#     5.                      "Energy"  0.139753 ##########
#     6.             "RootMeanSquared"  0.135650 #########
#     7.                "10Percentile"  0.135634 #########
#     8.                     "Maximum"  0.129204 #######
#     9.                  "Uniformity"  0.128465 #######
#    10.                     "Entropy"  0.118984 ###
#    11.                    "Skewness"  0.117570 ###
#    12.                     "Minimum"  0.114113 ##
#    13. "RobustMeanAbsoluteDeviation"  0.111644 #
#    14.          "InterquartileRange"  0.111096 #
#    15.                    "Variance"  0.108211
#    16.       "MeanAbsoluteDeviation"  0.107886
#    17.                       "Range"  0.107815
#    18.                    "Kurtosis"  0.107628
#
# Variable Importance: NUM_AS_ROOT:
#     1.     "TotalEnergy" 81.000000 ################
#     2.          "Energy" 62.000000 ############
#     3. "RootMeanSquared" 52.000000 ##########
#     4.            "Mean" 45.000000 ########
#     5.    "90Percentile" 32.000000 ######
#     6.          "Median" 12.000000 ##
#     7.         "Maximum"  9.000000 #
#     8.    "10Percentile"  4.000000
#     9.         "Minimum"  2.000000
#    10.      "Uniformity"  1.000000
#
# Variable Importance: NUM_NODES:
#     1.                    "Skewness" 3093.000000 ################
#     2.                     "Maximum" 2834.000000 #############
#     3.                  "Uniformity" 2656.000000 ###########
#     4.                      "Median" 2641.000000 ##########
#     5.                    "Kurtosis" 2553.000000 #########
#     6.                "90Percentile" 2510.000000 #########
#     7.                     "Minimum" 2441.000000 ########
#     8.                       "Range" 2331.000000 #######
#     9.                     "Entropy" 2265.000000 ######
#    10.          "InterquartileRange" 2195.000000 #####
#    11.                "10Percentile" 2115.000000 ####
#    12.                    "Variance" 2088.000000 ####
#    13. "RobustMeanAbsoluteDeviation" 2044.000000 ####
#    14.                        "Mean" 1987.000000 ###
#    15.       "MeanAbsoluteDeviation" 1960.000000 ###
#    16.                 "TotalEnergy" 1732.000000
#    17.                      "Energy" 1730.000000
#    18.             "RootMeanSquared" 1692.000000
#
# Variable Importance: SUM_SCORE:
#     1.                 "TotalEnergy" 207813.813552 ################
#     2.                      "Energy" 170109.012960 ############
#     3.                        "Mean" 152277.525368 ##########
#     4.             "RootMeanSquared" 147972.463223 ##########
#     5.                "90Percentile" 124052.661602 ########
#     6.                      "Median" 104402.253329 ######
#     7.                     "Maximum" 82284.766017 ####
#     8.                "10Percentile" 64266.453917 ##
#     9.                    "Skewness" 59828.966756 ##
#    10.                  "Uniformity" 59330.511453 ##
#    11.                     "Entropy" 46419.683170 #
#    12.                     "Minimum" 45378.877514 #
#    13.          "InterquartileRange" 39317.734807
#    14.                    "Kurtosis" 37107.368754
#    15. "RobustMeanAbsoluteDeviation" 37048.110691
#    16.                       "Range" 36781.403661
#    17.                    "Variance" 36389.520270
#    18.       "MeanAbsoluteDeviation" 33822.405372
#
#
#
# Winner takes all: true
# Out-of-bag evaluation: accuracy:0.815504 logloss:0.731193
# Number of trees: 300
# Total number of nodes: 82034
#
# Number of nodes by tree:
# Count: 300 Average: 273.447 StdDev: 16.0441
# Min: 233 Max: 327 Ignored: 0
# ----------------------------------------------
# [ 233, 237)  3   1.00%   1.00% #
# [ 237, 242)  2   0.67%   1.67%
# [ 242, 247)  6   2.00%   3.67% #
# [ 247, 252) 16   5.33%   9.00% ####
# [ 252, 256) 15   5.00%  14.00% ###
# [ 256, 261) 17   5.67%  19.67% ####
# [ 261, 266) 39  13.00%  32.67% #########
# [ 266, 271) 33  11.00%  43.67% ########
# [ 271, 275) 23   7.67%  51.33% #####
# [ 275, 280) 44  14.67%  66.00% ##########
# [ 280, 285) 27   9.00%  75.00% ######
# [ 285, 290) 29   9.67%  84.67% #######
# [ 290, 294) 17   5.67%  90.33% ####
# [ 294, 299) 13   4.33%  94.67% ###
# [ 299, 304)  6   2.00%  96.67% #
# [ 304, 309)  3   1.00%  97.67% #
# [ 309, 313)  2   0.67%  98.33%
# [ 313, 318)  4   1.33%  99.67% #
# [ 318, 323)  0   0.00%  99.67%
# [ 323, 327]  1   0.33% 100.00%
#
# Depth by leafs:
# Count: 41167 Average: 9.64914 StdDev: 2.8639
# Min: 2 Max: 15 Ignored: 0
# ----------------------------------------------
# [  2,  3)   91   0.22%   0.22%
# [  3,  4)  465   1.13%   1.35% #
# [  4,  5)  872   2.12%   3.47% ##
# [  5,  6) 1686   4.10%   7.56% ###
# [  6,  7) 2731   6.63%  14.20% #####
# [  7,  8) 3962   9.62%  23.82% #######
# [  8,  9) 4839  11.75%  35.58% #########
# [  9, 10) 5399  13.11%  48.69% ##########
# [ 10, 11) 5195  12.62%  61.31% ##########
# [ 11, 12) 4665  11.33%  72.64% #########
# [ 12, 13) 3855   9.36%  82.01% #######
# [ 13, 14) 3047   7.40%  89.41% ######
# [ 14, 15) 2228   5.41%  94.82% ####
# [ 15, 15] 2132   5.18% 100.00% ####
#
# Number of training obs by leaf:
# Count: 41167 Average: 55.5081 StdDev: 162.608
# Min: 5 Max: 1971 Ignored: 0
# ----------------------------------------------
# [    5,  103) 36813  89.42%  89.42% ##########
# [  103,  201)  1617   3.93%  93.35%
# [  201,  300)   884   2.15%  95.50%
# [  300,  398)   463   1.12%  96.62%
# [  398,  496)   339   0.82%  97.45%
# [  496,  595)   238   0.58%  98.03%
# [  595,  693)   157   0.38%  98.41%
# [  693,  791)   113   0.27%  98.68%
# [  791,  890)    82   0.20%  98.88%
# [  890,  988)    64   0.16%  99.04%
# [  988, 1086)    76   0.18%  99.22%
# [ 1086, 1185)    62   0.15%  99.37%
# [ 1185, 1283)    59   0.14%  99.51%
# [ 1283, 1381)    75   0.18%  99.70%
# [ 1381, 1480)    62   0.15%  99.85%
# [ 1480, 1578)    31   0.08%  99.92%
# [ 1578, 1676)    17   0.04%  99.96%
# [ 1676, 1775)    10   0.02%  99.99%
# [ 1775, 1873)     1   0.00%  99.99%
# [ 1873, 1971]     4   0.01% 100.00%
#
# Attribute in nodes:
# 	3093 : Skewness [NUMERICAL]
# 	2834 : Maximum [NUMERICAL]
# 	2656 : Uniformity [NUMERICAL]
# 	2641 : Median [NUMERICAL]
# 	2553 : Kurtosis [NUMERICAL]
# 	2510 : 90Percentile [NUMERICAL]
# 	2441 : Minimum [NUMERICAL]
# 	2331 : Range [NUMERICAL]
# 	2265 : Entropy [NUMERICAL]
# 	2195 : InterquartileRange [NUMERICAL]
# 	2115 : 10Percentile [NUMERICAL]
# 	2088 : Variance [NUMERICAL]
# 	2044 : RobustMeanAbsoluteDeviation [NUMERICAL]
# 	1987 : Mean [NUMERICAL]
# 	1960 : MeanAbsoluteDeviation [NUMERICAL]
# 	1732 : TotalEnergy [NUMERICAL]
# 	1730 : Energy [NUMERICAL]
# 	1692 : RootMeanSquared [NUMERICAL]
#
# Attribute in nodes with depth <= 0:
# 	81 : TotalEnergy [NUMERICAL]
# 	62 : Energy [NUMERICAL]
# 	52 : RootMeanSquared [NUMERICAL]
# 	45 : Mean [NUMERICAL]
# 	32 : 90Percentile [NUMERICAL]
# 	12 : Median [NUMERICAL]
# 	9 : Maximum [NUMERICAL]
# 	4 : 10Percentile [NUMERICAL]
# 	2 : Minimum [NUMERICAL]
# 	1 : Uniformity [NUMERICAL]
#
# Attribute in nodes with depth <= 1:
# 	176 : Mean [NUMERICAL]
# 	153 : TotalEnergy [NUMERICAL]
# 	135 : Energy [NUMERICAL]
# 	123 : RootMeanSquared [NUMERICAL]
# 	122 : Median [NUMERICAL]
# 	77 : 10Percentile [NUMERICAL]
# 	62 : 90Percentile [NUMERICAL]
# 	28 : Maximum [NUMERICAL]
# 	19 : Minimum [NUMERICAL]
# 	2 : Range [NUMERICAL]
# 	1 : Uniformity [NUMERICAL]
# 	1 : RobustMeanAbsoluteDeviation [NUMERICAL]
# 	1 : MeanAbsoluteDeviation [NUMERICAL]
#
# Attribute in nodes with depth <= 2:
# 	264 : Median [NUMERICAL]
# 	259 : Mean [NUMERICAL]
# 	230 : TotalEnergy [NUMERICAL]
# 	207 : Energy [NUMERICAL]
# 	188 : RootMeanSquared [NUMERICAL]
# 	151 : Skewness [NUMERICAL]
# 	136 : 10Percentile [NUMERICAL]
# 	111 : 90Percentile [NUMERICAL]
# 	82 : Maximum [NUMERICAL]
# 	77 : Uniformity [NUMERICAL]
# 	75 : Minimum [NUMERICAL]
# 	63 : Entropy [NUMERICAL]
# 	40 : RobustMeanAbsoluteDeviation [NUMERICAL]
# 	32 : InterquartileRange [NUMERICAL]
# 	29 : Kurtosis [NUMERICAL]
# 	23 : Range [NUMERICAL]
# 	23 : MeanAbsoluteDeviation [NUMERICAL]
# 	19 : Variance [NUMERICAL]
#
# Attribute in nodes with depth <= 3:
# 	374 : Median [NUMERICAL]
# 	361 : Mean [NUMERICAL]
# 	324 : Skewness [NUMERICAL]
# 	319 : TotalEnergy [NUMERICAL]
# 	288 : Energy [NUMERICAL]
# 	268 : RootMeanSquared [NUMERICAL]
# 	262 : 90Percentile [NUMERICAL]
# 	253 : Maximum [NUMERICAL]
# 	210 : 10Percentile [NUMERICAL]
# 	189 : Minimum [NUMERICAL]
# 	186 : Uniformity [NUMERICAL]
# 	143 : Entropy [NUMERICAL]
# 	133 : Kurtosis [NUMERICAL]
# 	111 : InterquartileRange [NUMERICAL]
# 	101 : RobustMeanAbsoluteDeviation [NUMERICAL]
# 	97 : Range [NUMERICAL]
# 	72 : MeanAbsoluteDeviation [NUMERICAL]
# 	71 : Variance [NUMERICAL]
#
# Attribute in nodes with depth <= 5:
# 	879 : Skewness [NUMERICAL]
# 	771 : Median [NUMERICAL]
# 	739 : Maximum [NUMERICAL]
# 	663 : 90Percentile [NUMERICAL]
# 	658 : Uniformity [NUMERICAL]
# 	625 : Mean [NUMERICAL]
# 	584 : Minimum [NUMERICAL]
# 	573 : TotalEnergy [NUMERICAL]
# 	524 : RootMeanSquared [NUMERICAL]
# 	515 : 10Percentile [NUMERICAL]
# 	502 : Energy [NUMERICAL]
# 	491 : Kurtosis [NUMERICAL]
# 	487 : Entropy [NUMERICAL]
# 	450 : Range [NUMERICAL]
# 	427 : InterquartileRange [NUMERICAL]
# 	394 : RobustMeanAbsoluteDeviation [NUMERICAL]
# 	352 : Variance [NUMERICAL]
# 	344 : MeanAbsoluteDeviation [NUMERICAL]
#
# Condition type in nodes:
# 	40867 : HigherCondition
# Condition type in nodes with depth <= 0:
# 	300 : HigherCondition
# Condition type in nodes with depth <= 1:
# 	900 : HigherCondition
# Condition type in nodes with depth <= 2:
# 	2009 : HigherCondition
# Condition type in nodes with depth <= 3:
# 	3762 : HigherCondition
# Condition type in nodes with depth <= 5:
# 	9978 : HigherCondition
# Node format: NOT_SET
#
# Training OOB:
# 	trees: 1, Out-of-bag evaluation: accuracy:0.773217 logloss:8.17409
# 	trees: 11, Out-of-bag evaluation: accuracy:0.799756 logloss:4.56881
# 	trees: 21, Out-of-bag evaluation: accuracy:0.8141 logloss:2.7719
# 	trees: 31, Out-of-bag evaluation: accuracy:0.815893 logloss:2.10906
# 	trees: 41, Out-of-bag evaluation: accuracy:0.815083 logloss:1.76808
# 	trees: 51, Out-of-bag evaluation: accuracy:0.815854 logloss:1.59583
# 	trees: 61, Out-of-bag evaluation: accuracy:0.813463 logloss:1.3892
# 	trees: 71, Out-of-bag evaluation: accuracy:0.812583 logloss:1.25303
# 	trees: 81, Out-of-bag evaluation: accuracy:0.814343 logloss:1.14906
# 	trees: 91, Out-of-bag evaluation: accuracy:0.815574 logloss:1.11478
# 	trees: 101, Out-of-bag evaluation: accuracy:0.814343 logloss:1.08552
# 	trees: 111, Out-of-bag evaluation: accuracy:0.814553 logloss:1.05212
# 	trees: 121, Out-of-bag evaluation: accuracy:0.813322 logloss:1.01828
# 	trees: 131, Out-of-bag evaluation: accuracy:0.812372 logloss:0.989274
# 	trees: 141, Out-of-bag evaluation: accuracy:0.812972 logloss:0.92143
# 	trees: 151, Out-of-bag evaluation: accuracy:0.813182 logloss:0.856763
# 	trees: 161, Out-of-bag evaluation: accuracy:0.814343 logloss:0.856756
# 	trees: 171, Out-of-bag evaluation: accuracy:0.813112 logloss:0.825564
# 	trees: 181, Out-of-bag evaluation: accuracy:0.815153 logloss:0.793682
# 	trees: 191, Out-of-bag evaluation: accuracy:0.815433 logloss:0.72931
# 	trees: 201, Out-of-bag evaluation: accuracy:0.815223 logloss:0.72912
# 	trees: 212, Out-of-bag evaluation: accuracy:0.814062 logloss:0.728649
# 	trees: 222, Out-of-bag evaluation: accuracy:0.817194 logloss:0.730006
# 	trees: 232, Out-of-bag evaluation: accuracy:0.815223 logloss:0.729584
# 	trees: 242, Out-of-bag evaluation: accuracy:0.814132 logloss:0.729719
# 	trees: 252, Out-of-bag evaluation: accuracy:0.814062 logloss:0.731072
# 	trees: 262, Out-of-bag evaluation: accuracy:0.815153 logloss:0.732658
# 	trees: 272, Out-of-bag evaluation: accuracy:0.815223 logloss:0.731418
# 	trees: 282, Out-of-bag evaluation: accuracy:0.814203 logloss:0.731101
# 	trees: 292, Out-of-bag evaluation: accuracy:0.814413 logloss:0.73159
# 	trees: 300, Out-of-bag evaluation: accuracy:0.815504 logloss:0.731193

# %%
# Model features
model.make_inspector().features()
# Out:
# ["10Percentile" (1; #0),
#  "90Percentile" (1; #1),
#  "Energy" (1; #2),
#  "Entropy" (1; #3),
#  "InterquartileRange" (1; #4),
#  "Kurtosis" (1; #5),
#  "Maximum" (1; #6),
#  "Mean" (1; #7),
#  "MeanAbsoluteDeviation" (1; #8),
#  "Median" (1; #9),
#  "Minimum" (1; #10),
#  "Range" (1; #11),
#  "RobustMeanAbsoluteDeviation" (1; #12),
#  "RootMeanSquared" (1; #13),
#  "Skewness" (1; #14),
#  "TotalEnergy" (1; #15),
#  "Uniformity" (1; #16),
#  "Variance" (1; #17)]

# %%
# Feature importance
model.make_inspector().variable_importances()
# Out:
# {'INV_MEAN_MIN_DEPTH': [("Median" (1; #9), 0.1548965864675204),
#   ("TotalEnergy" (1; #15), 0.1502943656982776),
#   ("Mean" (1; #7), 0.14578387605632112),
#   ("90Percentile" (1; #1), 0.141067406510243),
#   ("Energy" (1; #2), 0.13975263236234398),
#   ("RootMeanSquared" (1; #13), 0.1356501263761413),
#   ("10Percentile" (1; #0), 0.13563418447915115),
#   ("Maximum" (1; #6), 0.12920449605227244),
#   ("Uniformity" (1; #16), 0.12846537375042621),
#   ("Entropy" (1; #3), 0.11898367492734589),
#   ("Skewness" (1; #14), 0.11756994775957441),
#   ("Minimum" (1; #10), 0.1141130958735222),
#   ("RobustMeanAbsoluteDeviation" (1; #12), 0.11164389604484264),
#   ("InterquartileRange" (1; #4), 0.11109569197666623),
#   ("Variance" (1; #17), 0.10821120533730698),
#   ("MeanAbsoluteDeviation" (1; #8), 0.10788612621577129),
#   ("Range" (1; #11), 0.10781466169268498),
#   ("Kurtosis" (1; #5), 0.10762815656698112)],
#  'SUM_SCORE': [("TotalEnergy" (1; #15), 207813.81355171965),
#   ("Energy" (1; #2), 170109.0129604622),
#   ("Mean" (1; #7), 152277.52536824415),
#   ("RootMeanSquared" (1; #13), 147972.4632233248),
#   ("90Percentile" (1; #1), 124052.66160245964),
#   ("Median" (1; #9), 104402.25332893232),
#   ("Maximum" (1; #6), 82284.76601657148),
#   ("10Percentile" (1; #0), 64266.45391709741),
#   ("Skewness" (1; #14), 59828.96675558423),
#   ("Uniformity" (1; #16), 59330.51145272764),
#   ("Entropy" (1; #3), 46419.68316996993),
#   ("Minimum" (1; #10), 45378.87751408988),
#   ("InterquartileRange" (1; #4), 39317.73480733608),
#   ("Kurtosis" (1; #5), 37107.36875380927),
#   ("RobustMeanAbsoluteDeviation" (1; #12), 37048.11069147717),
#   ("Range" (1; #11), 36781.40366052315),
#   ("Variance" (1; #17), 36389.52027048314),
#   ("MeanAbsoluteDeviation" (1; #8), 33822.40537156652)],
#  'NUM_AS_ROOT': [("TotalEnergy" (1; #15), 81.0),
#   ("Energy" (1; #2), 62.0),
#   ("RootMeanSquared" (1; #13), 52.0),
#   ("Mean" (1; #7), 45.0),
#   ("90Percentile" (1; #1), 32.0),
#   ("Median" (1; #9), 12.0),
#   ("Maximum" (1; #6), 9.0),
#   ("10Percentile" (1; #0), 4.0),
#   ("Minimum" (1; #10), 2.0),
#   ("Uniformity" (1; #16), 1.0)],
#  'NUM_NODES': [("Skewness" (1; #14), 3093.0),
#   ("Maximum" (1; #6), 2834.0),
#   ("Uniformity" (1; #16), 2656.0),
#   ("Median" (1; #9), 2641.0),
#   ("Kurtosis" (1; #5), 2553.0),
#   ("90Percentile" (1; #1), 2510.0),
#   ("Minimum" (1; #10), 2441.0),
#   ("Range" (1; #11), 2331.0),
#   ("Entropy" (1; #3), 2265.0),
#   ("InterquartileRange" (1; #4), 2195.0),
#   ("10Percentile" (1; #0), 2115.0),
#   ("Variance" (1; #17), 2088.0),
#   ("RobustMeanAbsoluteDeviation" (1; #12), 2044.0),
#   ("Mean" (1; #7), 1987.0),
#   ("MeanAbsoluteDeviation" (1; #8), 1960.0),
#   ("TotalEnergy" (1; #15), 1732.0),
#   ("Energy" (1; #2), 1730.0),
#   ("RootMeanSquared" (1; #13), 1692.0)]}

# %%
# Model self evaluation
model.make_inspector().evaluation()
# Out:
# Evaluation(num_examples=7617, accuracy=0.8155035616017654, loss=0.7311928409170735, rmse=None, ndcg=None, aucs=None, auuc=None, qini=None)

# %%
logs = model.make_inspector().training_logs()

plt.figure(figsize=(12, 4))
plt.subplot(1, 2, 1)
plt.plot([log.num_trees for log in logs], [log.evaluation.accuracy for log in logs])
plt.xlabel("Number of trees")
plt.ylabel("Accuracy (out-of-bag)")
plt.subplot(1, 2, 2)
plt.plot([log.num_trees for log in logs], [log.evaluation.loss for log in logs])
plt.xlabel("Number of trees")
plt.ylabel("Logloss (out-of-bag)")
plt.show()

# %% [markdown]
# Calculate the score of our hold-out validation dataset

# %%
predictions = model.predict(val_ds)
y_true      = validation_data["label"]

from sklearn.metrics import roc_auc_score
ROC_AUC = roc_auc_score(y_true, predictions)
print("The ROC AUC score is %.5f" % ROC_AUC )
# Out:
# 1/2 [==============>...............] - ETA: 0s
# 2/2 [==============================] - 0s 4ms/step
# The ROC AUC score is 0.99222

# %%
# Compute binary classification metrics with sklearn
import numpy as np
from sklearn.metrics import (
    accuracy_score,
    precision_score,
    recall_score,
    f1_score,
    roc_auc_score,
    average_precision_score,
    confusion_matrix,
    classification_report,
    matthews_corrcoef,
    log_loss,
    brier_score_loss,
)

# Get predictions (probabilities or class labels)
preds = model.predict(test_ds)
# If model outputs probabilities, convert to labels by threshold 0.5
if preds.ndim == 2:
    # For TFDF classification, preds may be class probabilities with shape (N, 2)
    if preds.shape[1] == 2:
        pos_probs = preds[:, 1]
    else:
        # If single-probability column (positive class)
        pos_probs = preds[:, -1]
    y_pred = (pos_probs >= 0.5).astype(int)
else:
    # Already class labels
    y_pred = preds.astype(int)
    pos_probs = None

# Ground truth labels (must be 0/1 integers)
y_true = test_data["label"].astype(int).to_numpy()

# Core metrics
metrics = {}
metrics["accuracy"] = accuracy_score(y_true, y_pred)
metrics["precision"] = precision_score(y_true, y_pred, zero_division=0)
metrics["recall"] = recall_score(y_true, y_pred, zero_division=0)
metrics["f1"] = f1_score(y_true, y_pred, zero_division=0)
metrics["mcc"] = matthews_corrcoef(y_true, y_pred)

# Probabilistic metrics (only if we have probabilities)
if pos_probs is not None:
    metrics["roc_auc"] = roc_auc_score(y_true, pos_probs)
    metrics["pr_auc"] = average_precision_score(y_true, pos_probs)
    metrics["log_loss"] = log_loss(y_true, pos_probs, labels=[0,1])
    metrics["brier_score"] = brier_score_loss(y_true, pos_probs)

# Confusion matrix and detailed report
cm = confusion_matrix(y_true, y_pred, labels=[0,1])
report = classification_report(y_true, y_pred, digits=4)

print("Sklearn binary metrics:")
for k, v in metrics.items():
    print(f"{k}: {v:.4f}")
print("\nConfusion matrix:\n", cm)
print("\nClassification report:\n", report)
# Out:
# 1/3 [=========>....................] - ETA: 0s
# 3/3 [==============================] - 0s 10ms/step
# Sklearn binary metrics:
# accuracy: 0.9676
# precision: 0.8964
# recall: 0.7621
# f1: 0.8238
# mcc: 0.8093
# roc_auc: 0.9538
# pr_auc: 0.8549
# log_loss: 0.1376
# brier_score: 0.0280
#
# Confusion matrix:
#  [[2036   20]
#  [  54  173]]
#
# Classification report:
#                precision    recall  f1-score   support
#
#            0     0.9742    0.9903    0.9822      2056
#            1     0.8964    0.7621    0.8238       227
#
#     accuracy                         0.9676      2283
#    macro avg     0.9353    0.8762    0.9030      2283
# weighted avg     0.9664    0.9676    0.9664      2283
