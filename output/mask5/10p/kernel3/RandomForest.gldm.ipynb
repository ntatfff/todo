# %%
# Import packages and modules
import numpy  as np
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow_decision_forests as tfdf

from sklearn.model_selection import train_test_split
# Out:
# 2026-09-12 10:37:59.441396: I tensorflow/core/util/port.cc:113] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2026-09-12 10:37:59.789021: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2026-09-12 10:38:04.648602: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
# Check the version of TensorFlow Decision Forests
print("Found TensorFlow Decision Forests v" + tfdf.__version__)
# Out:
# Found TensorFlow Decision Forests v1.9.1

# %%
datasetPath = "dataset/10p/all/kernel3/"

# %%
# Parameters
datasetPath = "dataset/mask5/10p/gldm/kernel3/"

# %%
# train/validation/test = 70/10/20
train_data = pd.read_csv(f"{datasetPath}dataset.train.csv")
validation_data = pd.read_csv(f"{datasetPath}dataset.validation.csv")
test_data = pd.read_csv(f"{datasetPath}dataset.test.csv")

# %%
from sklearn.utils.class_weight import compute_class_weight

# tinh class weight tren tap train
classes = np.array([0, 1])
weights = compute_class_weight(class_weight="balanced", classes=classes, y=train_data["label"])
class_weight = {0: weights[0], 1: weights[1]}

# gan sample_weight cho tung dong
train_data["sample_weight"] = train_data["label"].map(class_weight)
validation_data["sample_weight"] = validation_data["label"].map(class_weight)
test_data["sample_weight"] = test_data["label"].map(class_weight)

# Convert the dataset into a TensorFlow dataset.
train_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    train_data, label="label", weight="sample_weight"
)         
val_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    validation_data, label="label", weight="sample_weight"
)
test_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    test_data, label="label", weight="sample_weight"
)
# Out:
# 2026-09-12 10:38:17.307592: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:984] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2026-09-12 10:38:17.309086: W tensorflow/core/common_runtime/gpu/gpu_device.cc:2251] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...

# %%
import keras

# %%
# %%time

# Train a Random Forest model.
model = tfdf.keras.RandomForestModel()

# Add evaluation metrics
model.compile(
    metrics=["accuracy"]
)
model.fit(x=train_ds)

# # Train a Gradient Boosted Trees model.
# model = tfdf.keras.GradientBoostedTreesModel(num_trees=1500)
# model.fit(train_ds)
# Out:
# Use /tmp/tmpns9wnwqd as temporary training directory
# Reading training dataset...
# Training dataset read in 0:00:02.540551. Found 7617 examples.
# Training model...
# Model trained in 0:00:00.519865
# Compiling model...
# [INFO 26-09-12 10:38:20.4193 UTC kernel.cc:1233] Loading model from path /tmp/tmpns9wnwqd/model/ with prefix cc4ed489b0d447a2
# [INFO 26-09-12 10:38:20.5152 UTC decision_forest.cc:734] Model loaded with 300 root(s), 76244 node(s), and 14 input feature(s).
# [INFO 26-09-12 10:38:20.5152 UTC abstract_model.cc:1362] Engine "RandomForestOptPred" built
# [INFO 26-09-12 10:38:20.5152 UTC kernel.cc:1061] Use fast generic engine
# Model compiled.
# CPU times: user 9.32 s, sys: 117 ms, total: 9.43 s
# Wall time: 6.13 s

# %%
# Evaluate the model
evaluate = model.evaluate(val_ds, return_dict=True)
print()

for name, value in evaluate.items():
    print(f"{name}: {value:.4f}")
# Out:
# WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 1/2 [==============>...............] - ETA: 2s - loss: 0.0000e+00 - accuracy: 0.9910
# 2/2 [==============================] - 3s 9ms/step - loss: 0.0000e+00 - accuracy: 0.9907
# loss: 0.0000
# accuracy: 0.9907

# %%
# Model Summary
model.summary()
# Out:
# Model: "random_forest_model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
# =================================================================
# Total params: 1 (1.00 Byte)
# Trainable params: 0 (0.00 Byte)
# Non-trainable params: 1 (1.00 Byte)
# _________________________________________________________________
# Type: "RANDOM_FOREST"
# Task: CLASSIFICATION
# Label: "__LABEL"
#
# Input Features (14):
# 	DependenceEntropy
# 	DependenceNonUniformity
# 	DependenceNonUniformityNormalized
# 	DependenceVariance
# 	GrayLevelNonUniformity
# 	GrayLevelVariance
# 	HighGrayLevelEmphasis
# 	LargeDependenceEmphasis
# 	LargeDependenceHighGrayLevelEmphasis
# 	LargeDependenceLowGrayLevelEmphasis
# 	LowGrayLevelEmphasis
# 	SmallDependenceEmphasis
# 	SmallDependenceHighGrayLevelEmphasis
# 	SmallDependenceLowGrayLevelEmphasis
#
# Trained with weights
#
# Variable Importance: INV_MEAN_MIN_DEPTH:
#     1.                "HighGrayLevelEmphasis"  0.245714 ################
#     2. "LargeDependenceHighGrayLevelEmphasis"  0.208298 ###########
#     3.                 "LowGrayLevelEmphasis"  0.183485 ########
#     4. "SmallDependenceHighGrayLevelEmphasis"  0.156884 #####
#     5.  "SmallDependenceLowGrayLevelEmphasis"  0.149092 ####
#     6.                    "DependenceEntropy"  0.148249 ####
#     7.  "LargeDependenceLowGrayLevelEmphasis"  0.127248 ##
#     8.               "GrayLevelNonUniformity"  0.124770 #
#     9.                    "GrayLevelVariance"  0.118307 #
#    10.              "SmallDependenceEmphasis"  0.117765 #
#    11.                   "DependenceVariance"  0.111025
#    12.              "LargeDependenceEmphasis"  0.109421
#    13.              "DependenceNonUniformity"  0.109118
#    14.    "DependenceNonUniformityNormalized"  0.108694
#
# Variable Importance: NUM_AS_ROOT:
#     1.                "HighGrayLevelEmphasis" 108.000000 ################
#     2.                 "LowGrayLevelEmphasis" 86.000000 ############
#     3. "SmallDependenceHighGrayLevelEmphasis" 46.000000 ######
#     4. "LargeDependenceHighGrayLevelEmphasis" 23.000000 ###
#     5.  "LargeDependenceLowGrayLevelEmphasis" 16.000000 ##
#     6.  "SmallDependenceLowGrayLevelEmphasis" 14.000000 #
#     7.               "GrayLevelNonUniformity"  5.000000
#     8.                    "DependenceEntropy"  2.000000
#
# Variable Importance: NUM_NODES:
#     1.                    "DependenceEntropy" 3555.000000 ################
#     2.                "HighGrayLevelEmphasis" 3479.000000 ###############
#     3. "LargeDependenceHighGrayLevelEmphasis" 3448.000000 ##############
#     4.               "GrayLevelNonUniformity" 2985.000000 ##########
#     5. "SmallDependenceHighGrayLevelEmphasis" 2936.000000 ##########
#     6.                 "LowGrayLevelEmphasis" 2928.000000 #########
#     7.  "SmallDependenceLowGrayLevelEmphasis" 2801.000000 ########
#     8.                    "GrayLevelVariance" 2763.000000 ########
#     9.              "SmallDependenceEmphasis" 2593.000000 ######
#    10.  "LargeDependenceLowGrayLevelEmphasis" 2402.000000 ####
#    11.                   "DependenceVariance" 2335.000000 ####
#    12.              "LargeDependenceEmphasis" 1938.000000
#    13.              "DependenceNonUniformity" 1912.000000
#    14.    "DependenceNonUniformityNormalized" 1897.000000
#
# Variable Importance: SUM_SCORE:
#     1.                "HighGrayLevelEmphasis" 341070.122762 ################
#     2.                 "LowGrayLevelEmphasis" 235400.252974 ##########
#     3. "LargeDependenceHighGrayLevelEmphasis" 193870.281655 ########
#     4. "SmallDependenceHighGrayLevelEmphasis" 161487.170177 ######
#     5.  "SmallDependenceLowGrayLevelEmphasis" 103962.018910 ###
#     6.                    "DependenceEntropy" 92009.236679 ###
#     7.  "LargeDependenceLowGrayLevelEmphasis" 74553.775326 ##
#     8.               "GrayLevelNonUniformity" 61366.259324 #
#     9.                    "GrayLevelVariance" 52369.065145 #
#    10.              "SmallDependenceEmphasis" 48379.531451
#    11.                   "DependenceVariance" 36460.945499
#    12.              "LargeDependenceEmphasis" 32523.757759
#    13.              "DependenceNonUniformity" 31455.461380
#    14.    "DependenceNonUniformityNormalized" 30295.597650
#
#
#
# Winner takes all: true
# Out-of-bag evaluation: accuracy:0.836932 logloss:0.684106
# Number of trees: 300
# Total number of nodes: 76244
#
# Number of nodes by tree:
# Count: 300 Average: 254.147 StdDev: 14.7012
# Min: 215 Max: 295 Ignored: 0
# ----------------------------------------------
# [ 215, 219)  1   0.33%   0.33%
# [ 219, 223)  4   1.33%   1.67% #
# [ 223, 227)  6   2.00%   3.67% ##
# [ 227, 231)  7   2.33%   6.00% ##
# [ 231, 235)  8   2.67%   8.67% ##
# [ 235, 239) 13   4.33%  13.00% ####
# [ 239, 243) 17   5.67%  18.67% #####
# [ 243, 247) 31  10.33%  29.00% #########
# [ 247, 251) 32  10.67%  39.67% #########
# [ 251, 255) 30  10.00%  49.67% #########
# [ 255, 259) 31  10.33%  60.00% #########
# [ 259, 263) 34  11.33%  71.33% ##########
# [ 263, 267) 24   8.00%  79.33% #######
# [ 267, 271) 21   7.00%  86.33% ######
# [ 271, 275) 16   5.33%  91.67% #####
# [ 275, 279)  7   2.33%  94.00% ##
# [ 279, 283)  9   3.00%  97.00% ###
# [ 283, 287)  4   1.33%  98.33% #
# [ 287, 291)  3   1.00%  99.33% #
# [ 291, 295]  2   0.67% 100.00% #
#
# Depth by leafs:
# Count: 38272 Average: 9.33649 StdDev: 2.84282
# Min: 2 Max: 15 Ignored: 0
# ----------------------------------------------
# [  2,  3)   13   0.03%   0.03%
# [  3,  4)  421   1.10%   1.13% #
# [  4,  5) 1009   2.64%   3.77% ##
# [  5,  6) 2078   5.43%   9.20% ####
# [  6,  7) 3101   8.10%  17.30% ######
# [  7,  8) 4070  10.63%  27.94% #########
# [  8,  9) 4761  12.44%  40.38% ##########
# [  9, 10) 4768  12.46%  52.83% ##########
# [ 10, 11) 4788  12.51%  65.35% ##########
# [ 11, 12) 4111  10.74%  76.09% #########
# [ 12, 13) 3362   8.78%  84.87% #######
# [ 13, 14) 2534   6.62%  91.49% #####
# [ 14, 15) 1712   4.47%  95.97% ####
# [ 15, 15] 1544   4.03% 100.00% ###
#
# Number of training obs by leaf:
# Count: 38272 Average: 59.7068 StdDev: 196.734
# Min: 5 Max: 2349 Ignored: 0
# ----------------------------------------------
# [    5,  122) 34847  91.05%  91.05% ##########
# [  122,  239)  1401   3.66%  94.71%
# [  239,  356)   555   1.45%  96.16%
# [  356,  474)   332   0.87%  97.03%
# [  474,  591)   205   0.54%  97.56%
# [  591,  708)   144   0.38%  97.94%
# [  708,  825)   122   0.32%  98.26%
# [  825,  943)    87   0.23%  98.49%
# [  943, 1060)    85   0.22%  98.71%
# [ 1060, 1177)    90   0.24%  98.94%
# [ 1177, 1294)    69   0.18%  99.12%
# [ 1294, 1412)    71   0.19%  99.31%
# [ 1412, 1529)    64   0.17%  99.48%
# [ 1529, 1646)    75   0.20%  99.67%
# [ 1646, 1763)    47   0.12%  99.80%
# [ 1763, 1881)    34   0.09%  99.89%
# [ 1881, 1998)    27   0.07%  99.96%
# [ 1998, 2115)    10   0.03%  99.98%
# [ 2115, 2232)     5   0.01%  99.99%
# [ 2232, 2349]     2   0.01% 100.00%
#
# Attribute in nodes:
# 	3555 : DependenceEntropy [NUMERICAL]
# 	3479 : HighGrayLevelEmphasis [NUMERICAL]
# 	3448 : LargeDependenceHighGrayLevelEmphasis [NUMERICAL]
# 	2985 : GrayLevelNonUniformity [NUMERICAL]
# 	2936 : SmallDependenceHighGrayLevelEmphasis [NUMERICAL]
# 	2928 : LowGrayLevelEmphasis [NUMERICAL]
# 	2801 : SmallDependenceLowGrayLevelEmphasis [NUMERICAL]
# 	2763 : GrayLevelVariance [NUMERICAL]
# 	2593 : SmallDependenceEmphasis [NUMERICAL]
# 	2402 : LargeDependenceLowGrayLevelEmphasis [NUMERICAL]
# 	2335 : DependenceVariance [NUMERICAL]
# 	1938 : LargeDependenceEmphasis [NUMERICAL]
# 	1912 : DependenceNonUniformity [NUMERICAL]
# 	1897 : DependenceNonUniformityNormalized [NUMERICAL]
#
# Attribute in nodes with depth <= 0:
# 	108 : HighGrayLevelEmphasis [NUMERICAL]
# 	86 : LowGrayLevelEmphasis [NUMERICAL]
# 	46 : SmallDependenceHighGrayLevelEmphasis [NUMERICAL]
# 	23 : LargeDependenceHighGrayLevelEmphasis [NUMERICAL]
# 	16 : LargeDependenceLowGrayLevelEmphasis [NUMERICAL]
# 	14 : SmallDependenceLowGrayLevelEmphasis [NUMERICAL]
# 	5 : GrayLevelNonUniformity [NUMERICAL]
# 	2 : DependenceEntropy [NUMERICAL]
#
# Attribute in nodes with depth <= 1:
# 	258 : HighGrayLevelEmphasis [NUMERICAL]
# 	186 : LowGrayLevelEmphasis [NUMERICAL]
# 	148 : LargeDependenceHighGrayLevelEmphasis [NUMERICAL]
# 	102 : SmallDependenceHighGrayLevelEmphasis [NUMERICAL]
# 	98 : SmallDependenceLowGrayLevelEmphasis [NUMERICAL]
# 	42 : LargeDependenceLowGrayLevelEmphasis [NUMERICAL]
# 	19 : GrayLevelNonUniformity [NUMERICAL]
# 	17 : SmallDependenceEmphasis [NUMERICAL]
# 	14 : DependenceEntropy [NUMERICAL]
# 	5 : DependenceVariance [NUMERICAL]
# 	4 : DependenceNonUniformityNormalized [NUMERICAL]
# 	3 : LargeDependenceEmphasis [NUMERICAL]
# 	2 : GrayLevelVariance [NUMERICAL]
# 	2 : DependenceNonUniformity [NUMERICAL]
#
# Attribute in nodes with depth <= 2:
# 	506 : HighGrayLevelEmphasis [NUMERICAL]
# 	336 : LargeDependenceHighGrayLevelEmphasis [NUMERICAL]
# 	308 : LowGrayLevelEmphasis [NUMERICAL]
# 	203 : SmallDependenceHighGrayLevelEmphasis [NUMERICAL]
# 	202 : SmallDependenceLowGrayLevelEmphasis [NUMERICAL]
# 	149 : DependenceEntropy [NUMERICAL]
# 	117 : LargeDependenceLowGrayLevelEmphasis [NUMERICAL]
# 	72 : GrayLevelNonUniformity [NUMERICAL]
# 	48 : SmallDependenceEmphasis [NUMERICAL]
# 	41 : GrayLevelVariance [NUMERICAL]
# 	29 : LargeDependenceEmphasis [NUMERICAL]
# 	26 : DependenceVariance [NUMERICAL]
# 	25 : DependenceNonUniformityNormalized [NUMERICAL]
# 	25 : DependenceNonUniformity [NUMERICAL]
#
# Attribute in nodes with depth <= 3:
# 	757 : HighGrayLevelEmphasis [NUMERICAL]
# 	600 : LargeDependenceHighGrayLevelEmphasis [NUMERICAL]
# 	489 : LowGrayLevelEmphasis [NUMERICAL]
# 	353 : DependenceEntropy [NUMERICAL]
# 	328 : SmallDependenceLowGrayLevelEmphasis [NUMERICAL]
# 	326 : SmallDependenceHighGrayLevelEmphasis [NUMERICAL]
# 	282 : GrayLevelNonUniformity [NUMERICAL]
# 	222 : LargeDependenceLowGrayLevelEmphasis [NUMERICAL]
# 	168 : GrayLevelVariance [NUMERICAL]
# 	134 : SmallDependenceEmphasis [NUMERICAL]
# 	100 : DependenceVariance [NUMERICAL]
# 	99 : LargeDependenceEmphasis [NUMERICAL]
# 	94 : DependenceNonUniformity [NUMERICAL]
# 	88 : DependenceNonUniformityNormalized [NUMERICAL]
#
# Attribute in nodes with depth <= 5:
# 	1361 : HighGrayLevelEmphasis [NUMERICAL]
# 	1242 : LargeDependenceHighGrayLevelEmphasis [NUMERICAL]
# 	1140 : DependenceEntropy [NUMERICAL]
# 	986 : LowGrayLevelEmphasis [NUMERICAL]
# 	848 : GrayLevelNonUniformity [NUMERICAL]
# 	834 : SmallDependenceHighGrayLevelEmphasis [NUMERICAL]
# 	820 : SmallDependenceLowGrayLevelEmphasis [NUMERICAL]
# 	625 : GrayLevelVariance [NUMERICAL]
# 	617 : LargeDependenceLowGrayLevelEmphasis [NUMERICAL]
# 	552 : SmallDependenceEmphasis [NUMERICAL]
# 	449 : DependenceVariance [NUMERICAL]
# 	406 : LargeDependenceEmphasis [NUMERICAL]
# 	398 : DependenceNonUniformityNormalized [NUMERICAL]
# 	375 : DependenceNonUniformity [NUMERICAL]
#
# Condition type in nodes:
# 	37972 : HigherCondition
# Condition type in nodes with depth <= 0:
# 	300 : HigherCondition
# Condition type in nodes with depth <= 1:
# 	900 : HigherCondition
# Condition type in nodes with depth <= 2:
# 	2087 : HigherCondition
# Condition type in nodes with depth <= 3:
# 	4040 : HigherCondition
# Condition type in nodes with depth <= 5:
# 	10653 : HigherCondition
# Node format: NOT_SET
#
# Training OOB:
# 	trees: 1, Out-of-bag evaluation: accuracy:0.852538 logloss:5.31508
# 	trees: 11, Out-of-bag evaluation: accuracy:0.810515 logloss:4.08509
# 	trees: 21, Out-of-bag evaluation: accuracy:0.825676 logloss:1.9348
# 	trees: 31, Out-of-bag evaluation: accuracy:0.827468 logloss:1.68783
# 	trees: 41, Out-of-bag evaluation: accuracy:0.828909 logloss:1.54424
# 	trees: 51, Out-of-bag evaluation: accuracy:0.832921 logloss:1.26526
# 	trees: 61, Out-of-bag evaluation: accuracy:0.830459 logloss:1.197
# 	trees: 71, Out-of-bag evaluation: accuracy:0.835421 logloss:1.12638
# 	trees: 81, Out-of-bag evaluation: accuracy:0.83271 logloss:0.992954
# 	trees: 91, Out-of-bag evaluation: accuracy:0.83183 logloss:0.957517
# 	trees: 101, Out-of-bag evaluation: accuracy:0.834961 logloss:0.920324
# 	trees: 111, Out-of-bag evaluation: accuracy:0.834681 logloss:0.919244
# 	trees: 121, Out-of-bag evaluation: accuracy:0.83331 logloss:0.919372
# 	trees: 131, Out-of-bag evaluation: accuracy:0.836792 logloss:0.886964
# 	trees: 141, Out-of-bag evaluation: accuracy:0.83433 logloss:0.850877
# 	trees: 151, Out-of-bag evaluation: accuracy:0.839783 logloss:0.849382
# 	trees: 161, Out-of-bag evaluation: accuracy:0.838622 logloss:0.814633
# 	trees: 171, Out-of-bag evaluation: accuracy:0.838482 logloss:0.81407
# 	trees: 181, Out-of-bag evaluation: accuracy:0.837742 logloss:0.813648
# 	trees: 191, Out-of-bag evaluation: accuracy:0.835842 logloss:0.74881
# 	trees: 201, Out-of-bag evaluation: accuracy:0.836652 logloss:0.749197
# 	trees: 211, Out-of-bag evaluation: accuracy:0.835842 logloss:0.74899
# 	trees: 221, Out-of-bag evaluation: accuracy:0.836932 logloss:0.749136
# 	trees: 231, Out-of-bag evaluation: accuracy:0.838093 logloss:0.717825
# 	trees: 241, Out-of-bag evaluation: accuracy:0.837353 logloss:0.717742
# 	trees: 251, Out-of-bag evaluation: accuracy:0.836932 logloss:0.716857
# 	trees: 261, Out-of-bag evaluation: accuracy:0.835982 logloss:0.716436
# 	trees: 271, Out-of-bag evaluation: accuracy:0.836932 logloss:0.716302
# 	trees: 281, Out-of-bag evaluation: accuracy:0.839043 logloss:0.683576
# 	trees: 291, Out-of-bag evaluation: accuracy:0.838903 logloss:0.683218
# 	trees: 300, Out-of-bag evaluation: accuracy:0.836932 logloss:0.684106

# %%
# Model features
model.make_inspector().features()
# Out:
# ["DependenceEntropy" (1; #0),
#  "DependenceNonUniformity" (1; #1),
#  "DependenceNonUniformityNormalized" (1; #2),
#  "DependenceVariance" (1; #3),
#  "GrayLevelNonUniformity" (1; #4),
#  "GrayLevelVariance" (1; #5),
#  "HighGrayLevelEmphasis" (1; #6),
#  "LargeDependenceEmphasis" (1; #7),
#  "LargeDependenceHighGrayLevelEmphasis" (1; #8),
#  "LargeDependenceLowGrayLevelEmphasis" (1; #9),
#  "LowGrayLevelEmphasis" (1; #10),
#  "SmallDependenceEmphasis" (1; #11),
#  "SmallDependenceHighGrayLevelEmphasis" (1; #12),
#  "SmallDependenceLowGrayLevelEmphasis" (1; #13)]

# %%
# Feature importance
model.make_inspector().variable_importances()
# Out:
# {'INV_MEAN_MIN_DEPTH': [("HighGrayLevelEmphasis" (1; #6), 0.24571382880530465),
#   ("LargeDependenceHighGrayLevelEmphasis" (1; #8), 0.2082979728668031),
#   ("LowGrayLevelEmphasis" (1; #10), 0.18348499483411707),
#   ("SmallDependenceHighGrayLevelEmphasis" (1; #12), 0.15688431004640754),
#   ("SmallDependenceLowGrayLevelEmphasis" (1; #13), 0.1490921930864018),
#   ("DependenceEntropy" (1; #0), 0.14824907386846625),
#   ("LargeDependenceLowGrayLevelEmphasis" (1; #9), 0.12724778386273228),
#   ("GrayLevelNonUniformity" (1; #4), 0.12477040514482617),
#   ("GrayLevelVariance" (1; #5), 0.11830735917863344),
#   ("SmallDependenceEmphasis" (1; #11), 0.11776478554642773),
#   ("DependenceVariance" (1; #3), 0.1110247217786185),
#   ("LargeDependenceEmphasis" (1; #7), 0.10942100640745034),
#   ("DependenceNonUniformity" (1; #1), 0.10911784621060926),
#   ("DependenceNonUniformityNormalized" (1; #2), 0.10869388330458071)],
#  'SUM_SCORE': [("HighGrayLevelEmphasis" (1; #6), 341070.12276217825),
#   ("LowGrayLevelEmphasis" (1; #10), 235400.2529735126),
#   ("LargeDependenceHighGrayLevelEmphasis" (1; #8), 193870.28165533452),
#   ("SmallDependenceHighGrayLevelEmphasis" (1; #12), 161487.1701772859),
#   ("SmallDependenceLowGrayLevelEmphasis" (1; #13), 103962.01891007244),
#   ("DependenceEntropy" (1; #0), 92009.23667863313),
#   ("LargeDependenceLowGrayLevelEmphasis" (1; #9), 74553.77532569152),
#   ("GrayLevelNonUniformity" (1; #4), 61366.25932385238),
#   ("GrayLevelVariance" (1; #5), 52369.06514460473),
#   ("SmallDependenceEmphasis" (1; #11), 48379.531451149574),
#   ("DependenceVariance" (1; #3), 36460.94549929704),
#   ("LargeDependenceEmphasis" (1; #7), 32523.757759398974),
#   ("DependenceNonUniformity" (1; #1), 31455.461379870932),
#   ("DependenceNonUniformityNormalized" (1; #2), 30295.597649592226)],
#  'NUM_AS_ROOT': [("HighGrayLevelEmphasis" (1; #6), 108.0),
#   ("LowGrayLevelEmphasis" (1; #10), 86.0),
#   ("SmallDependenceHighGrayLevelEmphasis" (1; #12), 46.0),
#   ("LargeDependenceHighGrayLevelEmphasis" (1; #8), 23.0),
#   ("LargeDependenceLowGrayLevelEmphasis" (1; #9), 16.0),
#   ("SmallDependenceLowGrayLevelEmphasis" (1; #13), 14.0),
#   ("GrayLevelNonUniformity" (1; #4), 5.0),
#   ("DependenceEntropy" (1; #0), 2.0)],
#  'NUM_NODES': [("DependenceEntropy" (1; #0), 3555.0),
#   ("HighGrayLevelEmphasis" (1; #6), 3479.0),
#   ("LargeDependenceHighGrayLevelEmphasis" (1; #8), 3448.0),
#   ("GrayLevelNonUniformity" (1; #4), 2985.0),
#   ("SmallDependenceHighGrayLevelEmphasis" (1; #12), 2936.0),
#   ("LowGrayLevelEmphasis" (1; #10), 2928.0),
#   ("SmallDependenceLowGrayLevelEmphasis" (1; #13), 2801.0),
#   ("GrayLevelVariance" (1; #5), 2763.0),
#   ("SmallDependenceEmphasis" (1; #11), 2593.0),
#   ("LargeDependenceLowGrayLevelEmphasis" (1; #9), 2402.0),
#   ("DependenceVariance" (1; #3), 2335.0),
#   ("LargeDependenceEmphasis" (1; #7), 1938.0),
#   ("DependenceNonUniformity" (1; #1), 1912.0),
#   ("DependenceNonUniformityNormalized" (1; #2), 1897.0)]}

# %%
# Model self evaluation
model.make_inspector().evaluation()
# Out:
# Evaluation(num_examples=7617, accuracy=0.8369321329248641, loss=0.684105596653585, rmse=None, ndcg=None, aucs=None, auuc=None, qini=None)

# %%
logs = model.make_inspector().training_logs()

plt.figure(figsize=(12, 4))
plt.subplot(1, 2, 1)
plt.plot([log.num_trees for log in logs], [log.evaluation.accuracy for log in logs])
plt.xlabel("Number of trees")
plt.ylabel("Accuracy (out-of-bag)")
plt.subplot(1, 2, 2)
plt.plot([log.num_trees for log in logs], [log.evaluation.loss for log in logs])
plt.xlabel("Number of trees")
plt.ylabel("Logloss (out-of-bag)")
plt.show()

# %% [markdown]
# Calculate the score of our hold-out validation dataset

# %%
predictions = model.predict(val_ds)
y_true      = validation_data["label"]

from sklearn.metrics import roc_auc_score
ROC_AUC = roc_auc_score(y_true, predictions)
print("The ROC AUC score is %.5f" % ROC_AUC )
# Out:
# 1/2 [==============>...............] - ETA: 0s
# 2/2 [==============================] - 0s 4ms/step
# The ROC AUC score is 0.99686

# %%
# Compute binary classification metrics with sklearn
import numpy as np
from sklearn.metrics import (
    accuracy_score,
    precision_score,
    recall_score,
    f1_score,
    roc_auc_score,
    average_precision_score,
    confusion_matrix,
    classification_report,
    matthews_corrcoef,
    log_loss,
    brier_score_loss,
)

# Get predictions (probabilities or class labels)
preds = model.predict(test_ds)
# If model outputs probabilities, convert to labels by threshold 0.5
if preds.ndim == 2:
    # For TFDF classification, preds may be class probabilities with shape (N, 2)
    if preds.shape[1] == 2:
        pos_probs = preds[:, 1]
    else:
        # If single-probability column (positive class)
        pos_probs = preds[:, -1]
    y_pred = (pos_probs >= 0.5).astype(int)
else:
    # Already class labels
    y_pred = preds.astype(int)
    pos_probs = None

# Ground truth labels (must be 0/1 integers)
y_true = test_data["label"].astype(int).to_numpy()

# Core metrics
metrics = {}
metrics["accuracy"] = accuracy_score(y_true, y_pred)
metrics["precision"] = precision_score(y_true, y_pred, zero_division=0)
metrics["recall"] = recall_score(y_true, y_pred, zero_division=0)
metrics["f1"] = f1_score(y_true, y_pred, zero_division=0)
metrics["mcc"] = matthews_corrcoef(y_true, y_pred)

# Probabilistic metrics (only if we have probabilities)
if pos_probs is not None:
    metrics["roc_auc"] = roc_auc_score(y_true, pos_probs)
    metrics["pr_auc"] = average_precision_score(y_true, pos_probs)
    metrics["log_loss"] = log_loss(y_true, pos_probs, labels=[0,1])
    metrics["brier_score"] = brier_score_loss(y_true, pos_probs)

# Confusion matrix and detailed report
cm = confusion_matrix(y_true, y_pred, labels=[0,1])
report = classification_report(y_true, y_pred, digits=4)

print("Sklearn binary metrics:")
for k, v in metrics.items():
    print(f"{k}: {v:.4f}")
print("\nConfusion matrix:\n", cm)
print("\nClassification report:\n", report)
# Out:
# 1/3 [=========>....................] - ETA: 0s
# 3/3 [==============================] - 0s 11ms/step
# Sklearn binary metrics:
# accuracy: 0.9645
# precision: 0.9011
# recall: 0.7225
# f1: 0.8020
# mcc: 0.7885
# roc_auc: 0.9556
# pr_auc: 0.8600
# log_loss: 0.1304
# brier_score: 0.0281
#
# Confusion matrix:
#  [[2038   18]
#  [  63  164]]
#
# Classification report:
#                precision    recall  f1-score   support
#
#            0     0.9700    0.9912    0.9805      2056
#            1     0.9011    0.7225    0.8020       227
#
#     accuracy                         0.9645      2283
#    macro avg     0.9356    0.8569    0.8912      2283
# weighted avg     0.9632    0.9645    0.9628      2283
