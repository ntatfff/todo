# %%
# Import packages and modules
import numpy  as np
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow_decision_forests as tfdf

from sklearn.model_selection import train_test_split
# Out:
# 2026-09-12 10:39:10.730288: I tensorflow/core/util/port.cc:113] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2026-09-12 10:39:11.090031: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2026-09-12 10:39:15.688685: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
# Check the version of TensorFlow Decision Forests
print("Found TensorFlow Decision Forests v" + tfdf.__version__)
# Out:
# Found TensorFlow Decision Forests v1.9.1

# %%
datasetPath = "dataset/10p/all/kernel3/"

# %%
# Parameters
datasetPath = "dataset/mask5/10p/glszm/kernel3/"

# %%
# train/validation/test = 70/10/20
train_data = pd.read_csv(f"{datasetPath}dataset.train.csv")
validation_data = pd.read_csv(f"{datasetPath}dataset.validation.csv")
test_data = pd.read_csv(f"{datasetPath}dataset.test.csv")

# %%
from sklearn.utils.class_weight import compute_class_weight

# tinh class weight tren tap train
classes = np.array([0, 1])
weights = compute_class_weight(class_weight="balanced", classes=classes, y=train_data["label"])
class_weight = {0: weights[0], 1: weights[1]}

# gan sample_weight cho tung dong
train_data["sample_weight"] = train_data["label"].map(class_weight)
validation_data["sample_weight"] = validation_data["label"].map(class_weight)
test_data["sample_weight"] = test_data["label"].map(class_weight)

# Convert the dataset into a TensorFlow dataset.
train_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    train_data, label="label", weight="sample_weight"
)         
val_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    validation_data, label="label", weight="sample_weight"
)
test_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    test_data, label="label", weight="sample_weight"
)
# Out:
# 2026-09-12 10:39:27.820527: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:984] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2026-09-12 10:39:27.821846: W tensorflow/core/common_runtime/gpu/gpu_device.cc:2251] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...

# %%
import keras

# %%
# %%time

# Train a Random Forest model.
model = tfdf.keras.RandomForestModel()

# Add evaluation metrics
model.compile(
    metrics=["accuracy"]
)
model.fit(x=train_ds)

# # Train a Gradient Boosted Trees model.
# model = tfdf.keras.GradientBoostedTreesModel(num_trees=1500)
# model.fit(train_ds)
# Out:
# Use /tmp/tmpp_t0_oy2 as temporary training directory
# Reading training dataset...
# Training dataset read in 0:00:02.593918. Found 7617 examples.
# Training model...
# Model trained in 0:00:00.533663
# Compiling model...
# [INFO 26-09-12 10:39:30.9962 UTC kernel.cc:1233] Loading model from path /tmp/tmpp_t0_oy2/model/ with prefix 599b980b5b7b4bdf
# [INFO 26-09-12 10:39:31.0984 UTC decision_forest.cc:734] Model loaded with 300 root(s), 79884 node(s), and 16 input feature(s).
# [INFO 26-09-12 10:39:31.0985 UTC abstract_model.cc:1362] Engine "RandomForestOptPred" built
# [INFO 26-09-12 10:39:31.0985 UTC kernel.cc:1061] Use fast generic engine
# Model compiled.
# CPU times: user 9.37 s, sys: 164 ms, total: 9.54 s
# Wall time: 6.25 s

# %%
# Evaluate the model
evaluate = model.evaluate(val_ds, return_dict=True)
print()

for name, value in evaluate.items():
    print(f"{name}: {value:.4f}")
# Out:
# WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 1/2 [==============>...............] - ETA: 3s - loss: 0.0000e+00 - accuracy: 0.9880
# 2/2 [==============================] - 4s 8ms/step - loss: 0.0000e+00 - accuracy: 0.9888
# loss: 0.0000
# accuracy: 0.9888

# %%
# Model Summary
model.summary()
# Out:
# Model: "random_forest_model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
# =================================================================
# Total params: 1 (1.00 Byte)
# Trainable params: 0 (0.00 Byte)
# Non-trainable params: 1 (1.00 Byte)
# _________________________________________________________________
# Type: "RANDOM_FOREST"
# Task: CLASSIFICATION
# Label: "__LABEL"
#
# Input Features (16):
# 	GrayLevelNonUniformity
# 	GrayLevelNonUniformityNormalized
# 	GrayLevelVariance
# 	HighGrayLevelZoneEmphasis
# 	LargeAreaEmphasis
# 	LargeAreaHighGrayLevelEmphasis
# 	LargeAreaLowGrayLevelEmphasis
# 	LowGrayLevelZoneEmphasis
# 	SizeZoneNonUniformity
# 	SizeZoneNonUniformityNormalized
# 	SmallAreaEmphasis
# 	SmallAreaHighGrayLevelEmphasis
# 	SmallAreaLowGrayLevelEmphasis
# 	ZoneEntropy
# 	ZonePercentage
# 	ZoneVariance
#
# Trained with weights
#
# Variable Importance: INV_MEAN_MIN_DEPTH:
#     1.        "HighGrayLevelZoneEmphasis"  0.210063 ################
#     2.           "GrayLevelNonUniformity"  0.180021 ###########
#     3.         "LowGrayLevelZoneEmphasis"  0.177912 ##########
#     4.   "LargeAreaHighGrayLevelEmphasis"  0.165327 #########
#     5.   "SmallAreaHighGrayLevelEmphasis"  0.158617 #######
#     6.    "SmallAreaLowGrayLevelEmphasis"  0.147602 ######
#     7.    "LargeAreaLowGrayLevelEmphasis"  0.138284 ####
#     8.                      "ZoneEntropy"  0.117925 #
#     9. "GrayLevelNonUniformityNormalized"  0.116788 #
#    10.                "GrayLevelVariance"  0.115334 #
#    11.                "SmallAreaEmphasis"  0.112295
#    12.  "SizeZoneNonUniformityNormalized"  0.111209
#    13.            "SizeZoneNonUniformity"  0.110636
#    14.                   "ZonePercentage"  0.109208
#    15.                "LargeAreaEmphasis"  0.107893
#    16.                     "ZoneVariance"  0.107634
#
# Variable Importance: NUM_AS_ROOT:
#     1.        "HighGrayLevelZoneEmphasis" 91.000000 ################
#     2.         "LowGrayLevelZoneEmphasis" 65.000000 ###########
#     3.   "SmallAreaHighGrayLevelEmphasis" 54.000000 #########
#     4.    "LargeAreaLowGrayLevelEmphasis" 25.000000 ####
#     5.    "SmallAreaLowGrayLevelEmphasis" 25.000000 ####
#     6.   "LargeAreaHighGrayLevelEmphasis" 21.000000 ###
#     7.           "GrayLevelNonUniformity"  7.000000 #
#     8.                      "ZoneEntropy"  6.000000
#     9.                     "ZoneVariance"  3.000000
#    10. "GrayLevelNonUniformityNormalized"  2.000000
#    11.                "LargeAreaEmphasis"  1.000000
#
# Variable Importance: NUM_NODES:
#     1.           "GrayLevelNonUniformity" 3364.000000 ################
#     2.        "HighGrayLevelZoneEmphasis" 3256.000000 ##############
#     3.   "SmallAreaHighGrayLevelEmphasis" 2913.000000 ###########
#     4.   "LargeAreaHighGrayLevelEmphasis" 2873.000000 ##########
#     5.    "LargeAreaLowGrayLevelEmphasis" 2829.000000 ##########
#     6.         "LowGrayLevelZoneEmphasis" 2776.000000 ##########
#     7.                "GrayLevelVariance" 2627.000000 ########
#     8.    "SmallAreaLowGrayLevelEmphasis" 2612.000000 ########
#     9. "GrayLevelNonUniformityNormalized" 2484.000000 #######
#    10.                      "ZoneEntropy" 2401.000000 ######
#    11.                "SmallAreaEmphasis" 2072.000000 ##
#    12.  "SizeZoneNonUniformityNormalized" 2008.000000 ##
#    13.            "SizeZoneNonUniformity" 1968.000000 #
#    14.                     "ZoneVariance" 1946.000000 #
#    15.                "LargeAreaEmphasis" 1867.000000
#    16.                   "ZonePercentage" 1796.000000
#
# Variable Importance: SUM_SCORE:
#     1.        "HighGrayLevelZoneEmphasis" 298276.677197 ################
#     2.         "LowGrayLevelZoneEmphasis" 222423.058549 ###########
#     3.   "SmallAreaHighGrayLevelEmphasis" 185406.968077 #########
#     4.    "SmallAreaLowGrayLevelEmphasis" 129155.838620 #####
#     5.           "GrayLevelNonUniformity" 119518.952321 #####
#     6.   "LargeAreaHighGrayLevelEmphasis" 110375.587249 ####
#     7.    "LargeAreaLowGrayLevelEmphasis" 92174.763260 ###
#     8. "GrayLevelNonUniformityNormalized" 48512.262210 #
#     9.                      "ZoneEntropy" 48174.146272 #
#    10.                "GrayLevelVariance" 46791.209039 #
#    11.                "SmallAreaEmphasis" 34869.797012
#    12.            "SizeZoneNonUniformity" 34746.341764
#    13.  "SizeZoneNonUniformityNormalized" 32768.724976
#    14.                     "ZoneVariance" 30200.346138
#    15.                "LargeAreaEmphasis" 29808.908251
#    16.                   "ZonePercentage" 29593.059887
#
#
#
# Winner takes all: true
# Out-of-bag evaluation: accuracy:0.838233 logloss:0.600498
# Number of trees: 300
# Total number of nodes: 79884
#
# Number of nodes by tree:
# Count: 300 Average: 266.28 StdDev: 15.4735
# Min: 223 Max: 309 Ignored: 0
# ----------------------------------------------
# [ 223, 227)  2   0.67%   0.67%
# [ 227, 231)  1   0.33%   1.00%
# [ 231, 236)  4   1.33%   2.33% #
# [ 236, 240)  4   1.33%   3.67% #
# [ 240, 244) 10   3.33%   7.00% ##
# [ 244, 249)  9   3.00%  10.00% ##
# [ 249, 253) 19   6.33%  16.33% ####
# [ 253, 257) 35  11.67%  28.00% ########
# [ 257, 262) 45  15.00%  43.00% ##########
# [ 262, 266) 23   7.67%  50.67% #####
# [ 266, 270) 27   9.00%  59.67% ######
# [ 270, 275) 25   8.33%  68.00% ######
# [ 275, 279) 30  10.00%  78.00% #######
# [ 279, 283) 19   6.33%  84.33% ####
# [ 283, 288) 19   6.33%  90.67% ####
# [ 288, 292) 11   3.67%  94.33% ##
# [ 292, 296)  7   2.33%  96.67% ##
# [ 296, 301)  5   1.67%  98.33% #
# [ 301, 305)  2   0.67%  99.00%
# [ 305, 309]  3   1.00% 100.00% #
#
# Depth by leafs:
# Count: 40092 Average: 9.3059 StdDev: 2.79014
# Min: 2 Max: 15 Ignored: 0
# ----------------------------------------------
# [  2,  3)   22   0.05%   0.05%
# [  3,  4)  318   0.79%   0.85% #
# [  4,  5) 1043   2.60%   3.45% ##
# [  5,  6) 2027   5.06%   8.51% ####
# [  6,  7) 3425   8.54%  17.05% ######
# [  7,  8) 4400  10.97%  28.02% ########
# [  8,  9) 5042  12.58%  40.60% ##########
# [  9, 10) 5297  13.21%  53.81% ##########
# [ 10, 11) 4981  12.42%  66.24% #########
# [ 11, 12) 4373  10.91%  77.14% ########
# [ 12, 13) 3393   8.46%  85.61% ######
# [ 13, 14) 2511   6.26%  91.87% #####
# [ 14, 15) 1744   4.35%  96.22% ###
# [ 15, 15] 1516   3.78% 100.00% ###
#
# Number of training obs by leaf:
# Count: 40092 Average: 56.9964 StdDev: 182.526
# Min: 5 Max: 2421 Ignored: 0
# ----------------------------------------------
# [    5,  125) 36410  90.82%  90.82% ##########
# [  125,  246)  1622   4.05%  94.86%
# [  246,  367)   647   1.61%  96.48%
# [  367,  488)   355   0.89%  97.36%
# [  488,  609)   210   0.52%  97.88%
# [  609,  730)   133   0.33%  98.22%
# [  730,  850)   140   0.35%  98.57%
# [  850,  971)   101   0.25%  98.82%
# [  971, 1092)    90   0.22%  99.04%
# [ 1092, 1213)    87   0.22%  99.26%
# [ 1213, 1334)    64   0.16%  99.42%
# [ 1334, 1455)    56   0.14%  99.56%
# [ 1455, 1576)    53   0.13%  99.69%
# [ 1576, 1696)    37   0.09%  99.78%
# [ 1696, 1817)    25   0.06%  99.85%
# [ 1817, 1938)    24   0.06%  99.91%
# [ 1938, 2059)    15   0.04%  99.94%
# [ 2059, 2180)    12   0.03%  99.97%
# [ 2180, 2301)     5   0.01%  99.99%
# [ 2301, 2421]     6   0.01% 100.00%
#
# Attribute in nodes:
# 	3364 : GrayLevelNonUniformity [NUMERICAL]
# 	3256 : HighGrayLevelZoneEmphasis [NUMERICAL]
# 	2913 : SmallAreaHighGrayLevelEmphasis [NUMERICAL]
# 	2873 : LargeAreaHighGrayLevelEmphasis [NUMERICAL]
# 	2829 : LargeAreaLowGrayLevelEmphasis [NUMERICAL]
# 	2776 : LowGrayLevelZoneEmphasis [NUMERICAL]
# 	2627 : GrayLevelVariance [NUMERICAL]
# 	2612 : SmallAreaLowGrayLevelEmphasis [NUMERICAL]
# 	2484 : GrayLevelNonUniformityNormalized [NUMERICAL]
# 	2401 : ZoneEntropy [NUMERICAL]
# 	2072 : SmallAreaEmphasis [NUMERICAL]
# 	2008 : SizeZoneNonUniformityNormalized [NUMERICAL]
# 	1968 : SizeZoneNonUniformity [NUMERICAL]
# 	1946 : ZoneVariance [NUMERICAL]
# 	1867 : LargeAreaEmphasis [NUMERICAL]
# 	1796 : ZonePercentage [NUMERICAL]
#
# Attribute in nodes with depth <= 0:
# 	91 : HighGrayLevelZoneEmphasis [NUMERICAL]
# 	65 : LowGrayLevelZoneEmphasis [NUMERICAL]
# 	54 : SmallAreaHighGrayLevelEmphasis [NUMERICAL]
# 	25 : SmallAreaLowGrayLevelEmphasis [NUMERICAL]
# 	25 : LargeAreaLowGrayLevelEmphasis [NUMERICAL]
# 	21 : LargeAreaHighGrayLevelEmphasis [NUMERICAL]
# 	7 : GrayLevelNonUniformity [NUMERICAL]
# 	6 : ZoneEntropy [NUMERICAL]
# 	3 : ZoneVariance [NUMERICAL]
# 	2 : GrayLevelNonUniformityNormalized [NUMERICAL]
# 	1 : LargeAreaEmphasis [NUMERICAL]
#
# Attribute in nodes with depth <= 1:
# 	207 : HighGrayLevelZoneEmphasis [NUMERICAL]
# 	177 : LowGrayLevelZoneEmphasis [NUMERICAL]
# 	112 : SmallAreaLowGrayLevelEmphasis [NUMERICAL]
# 	112 : SmallAreaHighGrayLevelEmphasis [NUMERICAL]
# 	106 : LargeAreaHighGrayLevelEmphasis [NUMERICAL]
# 	73 : GrayLevelNonUniformity [NUMERICAL]
# 	52 : LargeAreaLowGrayLevelEmphasis [NUMERICAL]
# 	14 : SizeZoneNonUniformityNormalized [NUMERICAL]
# 	12 : SmallAreaEmphasis [NUMERICAL]
# 	10 : ZoneEntropy [NUMERICAL]
# 	6 : SizeZoneNonUniformity [NUMERICAL]
# 	5 : LargeAreaEmphasis [NUMERICAL]
# 	5 : GrayLevelNonUniformityNormalized [NUMERICAL]
# 	4 : ZoneVariance [NUMERICAL]
# 	3 : GrayLevelVariance [NUMERICAL]
# 	2 : ZonePercentage [NUMERICAL]
#
# Attribute in nodes with depth <= 2:
# 	390 : HighGrayLevelZoneEmphasis [NUMERICAL]
# 	328 : LowGrayLevelZoneEmphasis [NUMERICAL]
# 	231 : GrayLevelNonUniformity [NUMERICAL]
# 	217 : SmallAreaHighGrayLevelEmphasis [NUMERICAL]
# 	215 : LargeAreaHighGrayLevelEmphasis [NUMERICAL]
# 	212 : SmallAreaLowGrayLevelEmphasis [NUMERICAL]
# 	146 : LargeAreaLowGrayLevelEmphasis [NUMERICAL]
# 	68 : ZoneEntropy [NUMERICAL]
# 	61 : GrayLevelNonUniformityNormalized [NUMERICAL]
# 	34 : SizeZoneNonUniformityNormalized [NUMERICAL]
# 	32 : ZonePercentage [NUMERICAL]
# 	31 : SizeZoneNonUniformity [NUMERICAL]
# 	31 : GrayLevelVariance [NUMERICAL]
# 	30 : SmallAreaEmphasis [NUMERICAL]
# 	30 : LargeAreaEmphasis [NUMERICAL]
# 	22 : ZoneVariance [NUMERICAL]
#
# Attribute in nodes with depth <= 3:
# 	629 : HighGrayLevelZoneEmphasis [NUMERICAL]
# 	495 : LowGrayLevelZoneEmphasis [NUMERICAL]
# 	478 : GrayLevelNonUniformity [NUMERICAL]
# 	388 : LargeAreaHighGrayLevelEmphasis [NUMERICAL]
# 	348 : SmallAreaLowGrayLevelEmphasis [NUMERICAL]
# 	343 : SmallAreaHighGrayLevelEmphasis [NUMERICAL]
# 	302 : LargeAreaLowGrayLevelEmphasis [NUMERICAL]
# 	187 : GrayLevelNonUniformityNormalized [NUMERICAL]
# 	184 : ZoneEntropy [NUMERICAL]
# 	138 : GrayLevelVariance [NUMERICAL]
# 	118 : ZonePercentage [NUMERICAL]
# 	113 : SizeZoneNonUniformity [NUMERICAL]
# 	102 : LargeAreaEmphasis [NUMERICAL]
# 	101 : SizeZoneNonUniformityNormalized [NUMERICAL]
# 	100 : SmallAreaEmphasis [NUMERICAL]
# 	90 : ZoneVariance [NUMERICAL]
#
# Attribute in nodes with depth <= 5:
# 	1243 : HighGrayLevelZoneEmphasis [NUMERICAL]
# 	1156 : GrayLevelNonUniformity [NUMERICAL]
# 	990 : LowGrayLevelZoneEmphasis [NUMERICAL]
# 	878 : LargeAreaHighGrayLevelEmphasis [NUMERICAL]
# 	870 : SmallAreaHighGrayLevelEmphasis [NUMERICAL]
# 	820 : LargeAreaLowGrayLevelEmphasis [NUMERICAL]
# 	752 : SmallAreaLowGrayLevelEmphasis [NUMERICAL]
# 	657 : GrayLevelNonUniformityNormalized [NUMERICAL]
# 	602 : ZoneEntropy [NUMERICAL]
# 	599 : GrayLevelVariance [NUMERICAL]
# 	462 : SizeZoneNonUniformity [NUMERICAL]
# 	442 : ZoneVariance [NUMERICAL]
# 	440 : ZonePercentage [NUMERICAL]
# 	437 : LargeAreaEmphasis [NUMERICAL]
# 	421 : SmallAreaEmphasis [NUMERICAL]
# 	419 : SizeZoneNonUniformityNormalized [NUMERICAL]
#
# Condition type in nodes:
# 	39792 : HigherCondition
# Condition type in nodes with depth <= 0:
# 	300 : HigherCondition
# Condition type in nodes with depth <= 1:
# 	900 : HigherCondition
# Condition type in nodes with depth <= 2:
# 	2078 : HigherCondition
# Condition type in nodes with depth <= 3:
# 	4116 : HigherCondition
# Condition type in nodes with depth <= 5:
# 	11188 : HigherCondition
# Node format: NOT_SET
#
# Training OOB:
# 	trees: 1, Out-of-bag evaluation: accuracy:0.807687 logloss:6.93165
# 	trees: 11, Out-of-bag evaluation: accuracy:0.82082 logloss:3.31399
# 	trees: 21, Out-of-bag evaluation: accuracy:0.829094 logloss:2.27549
# 	trees: 32, Out-of-bag evaluation: accuracy:0.824655 logloss:1.77937
# 	trees: 42, Out-of-bag evaluation: accuracy:0.83433 logloss:1.42764
# 	trees: 52, Out-of-bag evaluation: accuracy:0.837882 logloss:1.25674
# 	trees: 62, Out-of-bag evaluation: accuracy:0.831549 logloss:1.1206
# 	trees: 72, Out-of-bag evaluation: accuracy:0.836652 logloss:0.946605
# 	trees: 82, Out-of-bag evaluation: accuracy:0.835982 logloss:0.809732
# 	trees: 92, Out-of-bag evaluation: accuracy:0.835453 logloss:0.806927
# 	trees: 102, Out-of-bag evaluation: accuracy:0.835172 logloss:0.770859
# 	trees: 112, Out-of-bag evaluation: accuracy:0.836932 logloss:0.768618
# 	trees: 122, Out-of-bag evaluation: accuracy:0.837283 logloss:0.736042
# 	trees: 132, Out-of-bag evaluation: accuracy:0.837283 logloss:0.703238
# 	trees: 142, Out-of-bag evaluation: accuracy:0.835102 logloss:0.669
# 	trees: 152, Out-of-bag evaluation: accuracy:0.835032 logloss:0.668436
# 	trees: 162, Out-of-bag evaluation: accuracy:0.835912 logloss:0.669039
# 	trees: 172, Out-of-bag evaluation: accuracy:0.839043 logloss:0.665862
# 	trees: 182, Out-of-bag evaluation: accuracy:0.835032 logloss:0.666109
# 	trees: 192, Out-of-bag evaluation: accuracy:0.838093 logloss:0.664954
# 	trees: 202, Out-of-bag evaluation: accuracy:0.835842 logloss:0.664609
# 	trees: 212, Out-of-bag evaluation: accuracy:0.834681 logloss:0.633159
# 	trees: 222, Out-of-bag evaluation: accuracy:0.83183 logloss:0.631519
# 	trees: 232, Out-of-bag evaluation: accuracy:0.836932 logloss:0.630897
# 	trees: 242, Out-of-bag evaluation: accuracy:0.834961 logloss:0.631217
# 	trees: 252, Out-of-bag evaluation: accuracy:0.833941 logloss:0.600513
# 	trees: 262, Out-of-bag evaluation: accuracy:0.835912 logloss:0.600828
# 	trees: 272, Out-of-bag evaluation: accuracy:0.837072 logloss:0.600582
# 	trees: 282, Out-of-bag evaluation: accuracy:0.837002 logloss:0.599956
# 	trees: 292, Out-of-bag evaluation: accuracy:0.838303 logloss:0.600308
# 	trees: 300, Out-of-bag evaluation: accuracy:0.838233 logloss:0.600498

# %%
# Model features
model.make_inspector().features()
# Out:
# ["GrayLevelNonUniformity" (1; #0),
#  "GrayLevelNonUniformityNormalized" (1; #1),
#  "GrayLevelVariance" (1; #2),
#  "HighGrayLevelZoneEmphasis" (1; #3),
#  "LargeAreaEmphasis" (1; #4),
#  "LargeAreaHighGrayLevelEmphasis" (1; #5),
#  "LargeAreaLowGrayLevelEmphasis" (1; #6),
#  "LowGrayLevelZoneEmphasis" (1; #7),
#  "SizeZoneNonUniformity" (1; #8),
#  "SizeZoneNonUniformityNormalized" (1; #9),
#  "SmallAreaEmphasis" (1; #10),
#  "SmallAreaHighGrayLevelEmphasis" (1; #11),
#  "SmallAreaLowGrayLevelEmphasis" (1; #12),
#  "ZoneEntropy" (1; #13),
#  "ZonePercentage" (1; #14),
#  "ZoneVariance" (1; #15)]

# %%
# Feature importance
model.make_inspector().variable_importances()
# Out:
# {'INV_MEAN_MIN_DEPTH': [("HighGrayLevelZoneEmphasis" (1; #3),
#    0.21006331343160012),
#   ("GrayLevelNonUniformity" (1; #0), 0.1800208954510844),
#   ("LowGrayLevelZoneEmphasis" (1; #7), 0.1779117600523999),
#   ("LargeAreaHighGrayLevelEmphasis" (1; #5), 0.16532681953167636),
#   ("SmallAreaHighGrayLevelEmphasis" (1; #11), 0.15861715271951887),
#   ("SmallAreaLowGrayLevelEmphasis" (1; #12), 0.14760188667874508),
#   ("LargeAreaLowGrayLevelEmphasis" (1; #6), 0.13828441407094477),
#   ("ZoneEntropy" (1; #13), 0.11792467575757061),
#   ("GrayLevelNonUniformityNormalized" (1; #1), 0.11678820287362067),
#   ("GrayLevelVariance" (1; #2), 0.11533363355153566),
#   ("SmallAreaEmphasis" (1; #10), 0.11229467224826181),
#   ("SizeZoneNonUniformityNormalized" (1; #9), 0.11120915922874125),
#   ("SizeZoneNonUniformity" (1; #8), 0.11063602670463683),
#   ("ZonePercentage" (1; #14), 0.10920842870378351),
#   ("LargeAreaEmphasis" (1; #4), 0.1078930241101556),
#   ("ZoneVariance" (1; #15), 0.10763446444907514)],
#  'SUM_SCORE': [("HighGrayLevelZoneEmphasis" (1; #3), 298276.67719703494),
#   ("LowGrayLevelZoneEmphasis" (1; #7), 222423.05854862998),
#   ("SmallAreaHighGrayLevelEmphasis" (1; #11), 185406.96807660616),
#   ("SmallAreaLowGrayLevelEmphasis" (1; #12), 129155.83861954542),
#   ("GrayLevelNonUniformity" (1; #0), 119518.9523212474),
#   ("LargeAreaHighGrayLevelEmphasis" (1; #5), 110375.58724921028),
#   ("LargeAreaLowGrayLevelEmphasis" (1; #6), 92174.7632604184),
#   ("GrayLevelNonUniformityNormalized" (1; #1), 48512.26220980747),
#   ("ZoneEntropy" (1; #13), 48174.146272492755),
#   ("GrayLevelVariance" (1; #2), 46791.20903870042),
#   ("SmallAreaEmphasis" (1; #10), 34869.797012332565),
#   ("SizeZoneNonUniformity" (1; #8), 34746.341763815326),
#   ("SizeZoneNonUniformityNormalized" (1; #9), 32768.72497617038),
#   ("ZoneVariance" (1; #15), 30200.34613839832),
#   ("LargeAreaEmphasis" (1; #4), 29808.908251289693),
#   ("ZonePercentage" (1; #14), 29593.05988721393)],
#  'NUM_AS_ROOT': [("HighGrayLevelZoneEmphasis" (1; #3), 91.0),
#   ("LowGrayLevelZoneEmphasis" (1; #7), 65.0),
#   ("SmallAreaHighGrayLevelEmphasis" (1; #11), 54.0),
#   ("LargeAreaLowGrayLevelEmphasis" (1; #6), 25.0),
#   ("SmallAreaLowGrayLevelEmphasis" (1; #12), 25.0),
#   ("LargeAreaHighGrayLevelEmphasis" (1; #5), 21.0),
#   ("GrayLevelNonUniformity" (1; #0), 7.0),
#   ("ZoneEntropy" (1; #13), 6.0),
#   ("ZoneVariance" (1; #15), 3.0),
#   ("GrayLevelNonUniformityNormalized" (1; #1), 2.0),
#   ("LargeAreaEmphasis" (1; #4), 1.0)],
#  'NUM_NODES': [("GrayLevelNonUniformity" (1; #0), 3364.0),
#   ("HighGrayLevelZoneEmphasis" (1; #3), 3256.0),
#   ("SmallAreaHighGrayLevelEmphasis" (1; #11), 2913.0),
#   ("LargeAreaHighGrayLevelEmphasis" (1; #5), 2873.0),
#   ("LargeAreaLowGrayLevelEmphasis" (1; #6), 2829.0),
#   ("LowGrayLevelZoneEmphasis" (1; #7), 2776.0),
#   ("GrayLevelVariance" (1; #2), 2627.0),
#   ("SmallAreaLowGrayLevelEmphasis" (1; #12), 2612.0),
#   ("GrayLevelNonUniformityNormalized" (1; #1), 2484.0),
#   ("ZoneEntropy" (1; #13), 2401.0),
#   ("SmallAreaEmphasis" (1; #10), 2072.0),
#   ("SizeZoneNonUniformityNormalized" (1; #9), 2008.0),
#   ("SizeZoneNonUniformity" (1; #8), 1968.0),
#   ("ZoneVariance" (1; #15), 1946.0),
#   ("LargeAreaEmphasis" (1; #4), 1867.0),
#   ("ZonePercentage" (1; #14), 1796.0)]}

# %%
# Model self evaluation
model.make_inspector().evaluation()
# Out:
# Evaluation(num_examples=7617, accuracy=0.8382331640675105, loss=0.600498152185603, rmse=None, ndcg=None, aucs=None, auuc=None, qini=None)

# %%
logs = model.make_inspector().training_logs()

plt.figure(figsize=(12, 4))
plt.subplot(1, 2, 1)
plt.plot([log.num_trees for log in logs], [log.evaluation.accuracy for log in logs])
plt.xlabel("Number of trees")
plt.ylabel("Accuracy (out-of-bag)")
plt.subplot(1, 2, 2)
plt.plot([log.num_trees for log in logs], [log.evaluation.loss for log in logs])
plt.xlabel("Number of trees")
plt.ylabel("Logloss (out-of-bag)")
plt.show()

# %% [markdown]
# Calculate the score of our hold-out validation dataset

# %%
predictions = model.predict(val_ds)
y_true      = validation_data["label"]

from sklearn.metrics import roc_auc_score
ROC_AUC = roc_auc_score(y_true, predictions)
print("The ROC AUC score is %.5f" % ROC_AUC )
# Out:
# 1/2 [==============>...............] - ETA: 0s
# 2/2 [==============================] - 0s 4ms/step
# The ROC AUC score is 0.99540

# %%
# Compute binary classification metrics with sklearn
import numpy as np
from sklearn.metrics import (
    accuracy_score,
    precision_score,
    recall_score,
    f1_score,
    roc_auc_score,
    average_precision_score,
    confusion_matrix,
    classification_report,
    matthews_corrcoef,
    log_loss,
    brier_score_loss,
)

# Get predictions (probabilities or class labels)
preds = model.predict(test_ds)
# If model outputs probabilities, convert to labels by threshold 0.5
if preds.ndim == 2:
    # For TFDF classification, preds may be class probabilities with shape (N, 2)
    if preds.shape[1] == 2:
        pos_probs = preds[:, 1]
    else:
        # If single-probability column (positive class)
        pos_probs = preds[:, -1]
    y_pred = (pos_probs >= 0.5).astype(int)
else:
    # Already class labels
    y_pred = preds.astype(int)
    pos_probs = None

# Ground truth labels (must be 0/1 integers)
y_true = test_data["label"].astype(int).to_numpy()

# Core metrics
metrics = {}
metrics["accuracy"] = accuracy_score(y_true, y_pred)
metrics["precision"] = precision_score(y_true, y_pred, zero_division=0)
metrics["recall"] = recall_score(y_true, y_pred, zero_division=0)
metrics["f1"] = f1_score(y_true, y_pred, zero_division=0)
metrics["mcc"] = matthews_corrcoef(y_true, y_pred)

# Probabilistic metrics (only if we have probabilities)
if pos_probs is not None:
    metrics["roc_auc"] = roc_auc_score(y_true, pos_probs)
    metrics["pr_auc"] = average_precision_score(y_true, pos_probs)
    metrics["log_loss"] = log_loss(y_true, pos_probs, labels=[0,1])
    metrics["brier_score"] = brier_score_loss(y_true, pos_probs)

# Confusion matrix and detailed report
cm = confusion_matrix(y_true, y_pred, labels=[0,1])
report = classification_report(y_true, y_pred, digits=4)

print("Sklearn binary metrics:")
for k, v in metrics.items():
    print(f"{k}: {v:.4f}")
print("\nConfusion matrix:\n", cm)
print("\nClassification report:\n", report)
# Out:
# 1/3 [=========>....................] - ETA: 0s
# 3/3 [==============================] - 0s 11ms/step
# Sklearn binary metrics:
# accuracy: 0.9641
# precision: 0.9096
# recall: 0.7093
# f1: 0.7970
# mcc: 0.7849
# roc_auc: 0.9486
# pr_auc: 0.8424
# log_loss: 0.1552
# brier_score: 0.0305
#
# Confusion matrix:
#  [[2040   16]
#  [  66  161]]
#
# Classification report:
#                precision    recall  f1-score   support
#
#            0     0.9687    0.9922    0.9803      2056
#            1     0.9096    0.7093    0.7970       227
#
#     accuracy                         0.9641      2283
#    macro avg     0.9391    0.8507    0.8887      2283
# weighted avg     0.9628    0.9641    0.9621      2283
