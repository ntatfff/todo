# %%
# Import packages and modules
import numpy  as np
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow_decision_forests as tfdf

from sklearn.model_selection import train_test_split
# Out:
# 2026-09-12 10:37:22.969883: I tensorflow/core/util/port.cc:113] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2026-09-12 10:37:23.334129: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2026-09-12 10:37:28.127284: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
# Check the version of TensorFlow Decision Forests
print("Found TensorFlow Decision Forests v" + tfdf.__version__)
# Out:
# Found TensorFlow Decision Forests v1.9.1

# %%
datasetPath = "dataset/10p/all/kernel3/"

# %%
# Parameters
datasetPath = "dataset/mask5/10p/glcm/kernel3/"

# %%
# train/validation/test = 70/10/20
train_data = pd.read_csv(f"{datasetPath}dataset.train.csv")
validation_data = pd.read_csv(f"{datasetPath}dataset.validation.csv")
test_data = pd.read_csv(f"{datasetPath}dataset.test.csv")

# %%
from sklearn.utils.class_weight import compute_class_weight

# tinh class weight tren tap train
classes = np.array([0, 1])
weights = compute_class_weight(class_weight="balanced", classes=classes, y=train_data["label"])
class_weight = {0: weights[0], 1: weights[1]}

# gan sample_weight cho tung dong
train_data["sample_weight"] = train_data["label"].map(class_weight)
validation_data["sample_weight"] = validation_data["label"].map(class_weight)
test_data["sample_weight"] = test_data["label"].map(class_weight)

# Convert the dataset into a TensorFlow dataset.
train_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    train_data, label="label", weight="sample_weight"
)         
val_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    validation_data, label="label", weight="sample_weight"
)
test_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    test_data, label="label", weight="sample_weight"
)
# Out:
# 2026-09-12 10:37:42.246489: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:984] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2026-09-12 10:37:42.248225: W tensorflow/core/common_runtime/gpu/gpu_device.cc:2251] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...

# %%
import keras

# %%
# %%time

# Train a Random Forest model.
model = tfdf.keras.RandomForestModel()

# Add evaluation metrics
model.compile(
    metrics=["accuracy"]
)
model.fit(x=train_ds)

# # Train a Gradient Boosted Trees model.
# model = tfdf.keras.GradientBoostedTreesModel(num_trees=1500)
# model.fit(train_ds)
# Out:
# Use /tmp/tmpuobyzqyc as temporary training directory
# Reading training dataset...
# Training dataset read in 0:00:02.868158. Found 7617 examples.
# Training model...
# Model trained in 0:00:00.578861
# Compiling model...
# [INFO 26-09-12 10:37:45.8098 UTC kernel.cc:1233] Loading model from path /tmp/tmpuobyzqyc/model/ with prefix c051bc7ca5094deb
# [INFO 26-09-12 10:37:45.8987 UTC decision_forest.cc:734] Model loaded with 300 root(s), 66190 node(s), and 24 input feature(s).
# [INFO 26-09-12 10:37:45.8987 UTC abstract_model.cc:1362] Engine "RandomForestOptPred" built
# [INFO 26-09-12 10:37:45.8988 UTC kernel.cc:1061] Use fast generic engine
# Model compiled.
# CPU times: user 10.4 s, sys: 190 ms, total: 10.6 s
# Wall time: 6.64 s

# %%
# Evaluate the model
evaluate = model.evaluate(val_ds, return_dict=True)
print()

for name, value in evaluate.items():
    print(f"{name}: {value:.4f}")
# Out:
# WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 1/2 [==============>...............] - ETA: 2s - loss: 0.0000e+00 - accuracy: 0.9930
# 2/2 [==============================] - 3s 8ms/step - loss: 0.0000e+00 - accuracy: 0.9926
# loss: 0.0000
# accuracy: 0.9926

# %%
# Model Summary
model.summary()
# Out:
# Model: "random_forest_model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
# =================================================================
# Total params: 1 (1.00 Byte)
# Trainable params: 0 (0.00 Byte)
# Non-trainable params: 1 (1.00 Byte)
# _________________________________________________________________
# Type: "RANDOM_FOREST"
# Task: CLASSIFICATION
# Label: "__LABEL"
#
# Input Features (24):
# 	Autocorrelation
# 	ClusterProminence
# 	ClusterShade
# 	ClusterTendency
# 	Contrast
# 	Correlation
# 	DifferenceAverage
# 	DifferenceEntropy
# 	DifferenceVariance
# 	Id
# 	Idm
# 	Idmn
# 	Idn
# 	Imc1
# 	Imc2
# 	InverseVariance
# 	JointAverage
# 	JointEnergy
# 	JointEntropy
# 	MCC
# 	MaximumProbability
# 	SumAverage
# 	SumEntropy
# 	SumSquares
#
# Trained with weights
#
# Variable Importance: INV_MEAN_MIN_DEPTH:
#     1.    "Autocorrelation"  0.194630 ################
#     2.       "JointAverage"  0.188775 ##############
#     3.         "SumAverage"  0.176958 ############
#     4.    "InverseVariance"  0.133727 ####
#     5.        "Correlation"  0.131771 ####
#     6.         "SumEntropy"  0.125250 ###
#     7.                "Idn"  0.122879 ##
#     8.               "Imc1"  0.122805 ##
#     9.                "Idm"  0.122623 ##
#    10.                "MCC"  0.121960 ##
#    11.               "Idmn"  0.121199 ##
#    12.                 "Id"  0.117863 #
#    13.  "DifferenceEntropy"  0.116937 #
#    14. "MaximumProbability"  0.116681 #
#    15.       "ClusterShade"  0.116672 #
#    16.  "DifferenceAverage"  0.116404 #
#    17.               "Imc2"  0.115807 #
#    18.        "JointEnergy"  0.114284 #
#    19.       "JointEntropy"  0.113474 #
#    20.           "Contrast"  0.112542
#    21. "DifferenceVariance"  0.111815
#    22.  "ClusterProminence"  0.109863
#    23.         "SumSquares"  0.107797
#    24.    "ClusterTendency"  0.107748
#
# Variable Importance: NUM_AS_ROOT:
#     1.    "Autocorrelation" 66.000000 ################
#     2.       "JointAverage" 60.000000 ##############
#     3.         "SumAverage" 54.000000 #############
#     4.         "SumEntropy" 36.000000 ########
#     5.        "Correlation" 17.000000 ###
#     6.       "JointEntropy" 17.000000 ###
#     7.                "MCC" 14.000000 ###
#     8.        "JointEnergy" 10.000000 ##
#     9.               "Imc1"  9.000000 #
#    10.               "Imc2"  8.000000 #
#    11. "MaximumProbability"  8.000000 #
#    12.  "ClusterProminence"  1.000000
#
# Variable Importance: NUM_NODES:
#     1.                "Idn" 2602.000000 ################
#     2.               "Idmn" 2205.000000 ############
#     3.       "JointAverage" 2107.000000 ###########
#     4.    "Autocorrelation" 2085.000000 ###########
#     5.         "SumAverage" 2008.000000 ##########
#     6.       "ClusterShade" 1694.000000 #######
#     7.        "Correlation" 1537.000000 ######
#     8.    "InverseVariance" 1435.000000 #####
#     9.               "Imc1" 1297.000000 ####
#    10.                "MCC" 1227.000000 ###
#    11. "DifferenceVariance" 1220.000000 ###
#    12.           "Contrast" 1198.000000 ###
#    13.  "DifferenceAverage" 1155.000000 ###
#    14.  "DifferenceEntropy" 1146.000000 ###
#    15.                "Idm" 1142.000000 ###
#    16.         "SumEntropy" 1128.000000 ##
#    17. "MaximumProbability" 1092.000000 ##
#    18.               "Imc2" 1091.000000 ##
#    19.                 "Id" 1056.000000 ##
#    20.  "ClusterProminence" 1044.000000 ##
#    21.        "JointEnergy" 931.000000 #
#    22.       "JointEntropy" 885.000000
#    23.         "SumSquares" 856.000000
#    24.    "ClusterTendency" 804.000000
#
# Variable Importance: SUM_SCORE:
#     1.    "Autocorrelation" 286970.577554 ################
#     2.       "JointAverage" 272211.729282 ###############
#     3.         "SumAverage" 246983.781120 #############
#     4.                "Idn" 75256.629440 ###
#     5.               "Idmn" 66732.805158 ###
#     6.    "InverseVariance" 59242.249230 ##
#     7.        "Correlation" 44312.410098 #
#     8.                "Idm" 38861.891888 #
#     9.               "Imc1" 36746.219766 #
#    10.         "SumEntropy" 35707.143891 #
#    11.       "ClusterShade" 34508.908143 #
#    12.                 "Id" 32101.405163
#    13.                "MCC" 31132.845906
#    14.  "DifferenceEntropy" 30637.504081
#    15.  "DifferenceAverage" 30178.409326
#    16. "MaximumProbability" 27293.731182
#    17.               "Imc2" 26899.313486
#    18.           "Contrast" 25652.224399
#    19. "DifferenceVariance" 24626.962345
#    20.        "JointEnergy" 23716.590473
#    21.       "JointEntropy" 20953.142781
#    22.  "ClusterProminence" 19727.378262
#    23.    "ClusterTendency" 15386.096910
#    24.         "SumSquares" 15378.100945
#
#
#
# Winner takes all: true
# Out-of-bag evaluation: accuracy:0.874113 logloss:0.344915
# Number of trees: 300
# Total number of nodes: 66190
#
# Number of nodes by tree:
# Count: 300 Average: 220.633 StdDev: 15.7603
# Min: 179 Max: 295 Ignored: 0
# ----------------------------------------------
# [ 179, 184)  2   0.67%   0.67%
# [ 184, 190)  7   2.33%   3.00% #
# [ 190, 196) 12   4.00%   7.00% ##
# [ 196, 202) 10   3.33%  10.33% ##
# [ 202, 208) 30  10.00%  20.33% #####
# [ 208, 214) 35  11.67%  32.00% ######
# [ 214, 219) 27   9.00%  41.00% #####
# [ 219, 225) 57  19.00%  60.00% ##########
# [ 225, 231) 47  15.67%  75.67% ########
# [ 231, 237) 24   8.00%  83.67% ####
# [ 237, 243) 24   8.00%  91.67% ####
# [ 243, 249) 15   5.00%  96.67% ###
# [ 249, 255)  5   1.67%  98.33% #
# [ 255, 260)  3   1.00%  99.33% #
# [ 260, 266)  1   0.33%  99.67%
# [ 266, 272)  0   0.00%  99.67%
# [ 272, 278)  0   0.00%  99.67%
# [ 278, 284)  0   0.00%  99.67%
# [ 284, 290)  0   0.00%  99.67%
# [ 290, 295]  1   0.33% 100.00%
#
# Depth by leafs:
# Count: 33245 Average: 8.78162 StdDev: 2.57804
# Min: 1 Max: 15 Ignored: 0
# ----------------------------------------------
# [  1,  2)    3   0.01%   0.01%
# [  2,  3)   61   0.18%   0.19%
# [  3,  4)  319   0.96%   1.15% #
# [  4,  5) 1017   3.06%   4.21% ##
# [  5,  6) 1975   5.94%  10.15% ####
# [  6,  7) 3215   9.67%  19.82% #######
# [  7,  8) 4233  12.73%  32.56% #########
# [  8,  9) 4809  14.47%  47.02% ##########
# [  9, 10) 4737  14.25%  61.27% ##########
# [ 10, 11) 4377  13.17%  74.44% #########
# [ 11, 12) 3429  10.31%  84.75% #######
# [ 12, 13) 2276   6.85%  91.60% #####
# [ 13, 14) 1501   4.51%  96.11% ###
# [ 14, 15)  815   2.45%  98.56% ##
# [ 15, 15]  478   1.44% 100.00% #
#
# Number of training obs by leaf:
# Count: 33245 Average: 68.7351 StdDev: 200.849
# Min: 5 Max: 2293 Ignored: 0
# ----------------------------------------------
# [    5,  119) 29500  88.74%  88.74% ##########
# [  119,  233)  1458   4.39%  93.12%
# [  233,  348)   626   1.88%  95.00%
# [  348,  462)   374   1.12%  96.13%
# [  462,  577)   293   0.88%  97.01%
# [  577,  691)   209   0.63%  97.64%
# [  691,  806)   135   0.41%  98.04%
# [  806,  920)   119   0.36%  98.40%
# [  920, 1035)    95   0.29%  98.69%
# [ 1035, 1149)    82   0.25%  98.94%
# [ 1149, 1263)   103   0.31%  99.24%
# [ 1263, 1378)    70   0.21%  99.46%
# [ 1378, 1492)    36   0.11%  99.56%
# [ 1492, 1607)    36   0.11%  99.67%
# [ 1607, 1721)    34   0.10%  99.77%
# [ 1721, 1836)    25   0.08%  99.85%
# [ 1836, 1950)    21   0.06%  99.91%
# [ 1950, 2065)    17   0.05%  99.96%
# [ 2065, 2179)     6   0.02%  99.98%
# [ 2179, 2293]     6   0.02% 100.00%
#
# Attribute in nodes:
# 	2602 : Idn [NUMERICAL]
# 	2205 : Idmn [NUMERICAL]
# 	2107 : JointAverage [NUMERICAL]
# 	2085 : Autocorrelation [NUMERICAL]
# 	2008 : SumAverage [NUMERICAL]
# 	1694 : ClusterShade [NUMERICAL]
# 	1537 : Correlation [NUMERICAL]
# 	1435 : InverseVariance [NUMERICAL]
# 	1297 : Imc1 [NUMERICAL]
# 	1227 : MCC [NUMERICAL]
# 	1220 : DifferenceVariance [NUMERICAL]
# 	1198 : Contrast [NUMERICAL]
# 	1155 : DifferenceAverage [NUMERICAL]
# 	1146 : DifferenceEntropy [NUMERICAL]
# 	1142 : Idm [NUMERICAL]
# 	1128 : SumEntropy [NUMERICAL]
# 	1092 : MaximumProbability [NUMERICAL]
# 	1091 : Imc2 [NUMERICAL]
# 	1056 : Id [NUMERICAL]
# 	1044 : ClusterProminence [NUMERICAL]
# 	931 : JointEnergy [NUMERICAL]
# 	885 : JointEntropy [NUMERICAL]
# 	856 : SumSquares [NUMERICAL]
# 	804 : ClusterTendency [NUMERICAL]
#
# Attribute in nodes with depth <= 0:
# 	66 : Autocorrelation [NUMERICAL]
# 	60 : JointAverage [NUMERICAL]
# 	54 : SumAverage [NUMERICAL]
# 	36 : SumEntropy [NUMERICAL]
# 	17 : JointEntropy [NUMERICAL]
# 	17 : Correlation [NUMERICAL]
# 	14 : MCC [NUMERICAL]
# 	10 : JointEnergy [NUMERICAL]
# 	9 : Imc1 [NUMERICAL]
# 	8 : MaximumProbability [NUMERICAL]
# 	8 : Imc2 [NUMERICAL]
# 	1 : ClusterProminence [NUMERICAL]
#
# Attribute in nodes with depth <= 1:
# 	189 : Autocorrelation [NUMERICAL]
# 	180 : JointAverage [NUMERICAL]
# 	164 : SumAverage [NUMERICAL]
# 	48 : SumEntropy [NUMERICAL]
# 	46 : Correlation [NUMERICAL]
# 	33 : InverseVariance [NUMERICAL]
# 	29 : MCC [NUMERICAL]
# 	25 : Imc1 [NUMERICAL]
# 	24 : JointEnergy [NUMERICAL]
# 	23 : MaximumProbability [NUMERICAL]
# 	23 : JointEntropy [NUMERICAL]
# 	21 : Imc2 [NUMERICAL]
# 	13 : Id [NUMERICAL]
# 	13 : DifferenceAverage [NUMERICAL]
# 	12 : Idmn [NUMERICAL]
# 	12 : Idm [NUMERICAL]
# 	11 : DifferenceEntropy [NUMERICAL]
# 	10 : DifferenceVariance [NUMERICAL]
# 	8 : Contrast [NUMERICAL]
# 	6 : Idn [NUMERICAL]
# 	4 : SumSquares [NUMERICAL]
# 	1 : ClusterTendency [NUMERICAL]
# 	1 : ClusterShade [NUMERICAL]
# 	1 : ClusterProminence [NUMERICAL]
#
# Attribute in nodes with depth <= 2:
# 	339 : JointAverage [NUMERICAL]
# 	327 : Autocorrelation [NUMERICAL]
# 	309 : SumAverage [NUMERICAL]
# 	130 : Correlation [NUMERICAL]
# 	112 : InverseVariance [NUMERICAL]
# 	75 : SumEntropy [NUMERICAL]
# 	74 : Imc1 [NUMERICAL]
# 	61 : Idm [NUMERICAL]
# 	59 : DifferenceAverage [NUMERICAL]
# 	56 : MCC [NUMERICAL]
# 	52 : Id [NUMERICAL]
# 	51 : Imc2 [NUMERICAL]
# 	50 : ClusterShade [NUMERICAL]
# 	48 : DifferenceEntropy [NUMERICAL]
# 	46 : MaximumProbability [NUMERICAL]
# 	41 : JointEnergy [NUMERICAL]
# 	33 : Contrast [NUMERICAL]
# 	32 : JointEntropy [NUMERICAL]
# 	32 : DifferenceVariance [NUMERICAL]
# 	29 : Idmn [NUMERICAL]
# 	25 : Idn [NUMERICAL]
# 	19 : ClusterProminence [NUMERICAL]
# 	17 : SumSquares [NUMERICAL]
# 	13 : ClusterTendency [NUMERICAL]
#
# Attribute in nodes with depth <= 3:
# 	531 : Autocorrelation [NUMERICAL]
# 	530 : JointAverage [NUMERICAL]
# 	508 : SumAverage [NUMERICAL]
# 	234 : Correlation [NUMERICAL]
# 	199 : InverseVariance [NUMERICAL]
# 	175 : ClusterShade [NUMERICAL]
# 	168 : Imc1 [NUMERICAL]
# 	132 : MCC [NUMERICAL]
# 	124 : SumEntropy [NUMERICAL]
# 	122 : Idn [NUMERICAL]
# 	122 : Idm [NUMERICAL]
# 	121 : Imc2 [NUMERICAL]
# 	118 : DifferenceAverage [NUMERICAL]
# 	117 : Id [NUMERICAL]
# 	113 : DifferenceEntropy [NUMERICAL]
# 	108 : Idmn [NUMERICAL]
# 	98 : DifferenceVariance [NUMERICAL]
# 	82 : MaximumProbability [NUMERICAL]
# 	82 : Contrast [NUMERICAL]
# 	71 : ClusterProminence [NUMERICAL]
# 	70 : JointEnergy [NUMERICAL]
# 	61 : JointEntropy [NUMERICAL]
# 	48 : SumSquares [NUMERICAL]
# 	43 : ClusterTendency [NUMERICAL]
#
# Attribute in nodes with depth <= 5:
# 	995 : JointAverage [NUMERICAL]
# 	985 : Autocorrelation [NUMERICAL]
# 	899 : SumAverage [NUMERICAL]
# 	642 : Idn [NUMERICAL]
# 	569 : ClusterShade [NUMERICAL]
# 	550 : Correlation [NUMERICAL]
# 	548 : Idmn [NUMERICAL]
# 	509 : InverseVariance [NUMERICAL]
# 	457 : Imc1 [NUMERICAL]
# 	424 : MCC [NUMERICAL]
# 	374 : Idm [NUMERICAL]
# 	366 : DifferenceAverage [NUMERICAL]
# 	350 : Id [NUMERICAL]
# 	334 : SumEntropy [NUMERICAL]
# 	334 : DifferenceEntropy [NUMERICAL]
# 	332 : DifferenceVariance [NUMERICAL]
# 	325 : Imc2 [NUMERICAL]
# 	301 : Contrast [NUMERICAL]
# 	290 : MaximumProbability [NUMERICAL]
# 	244 : ClusterProminence [NUMERICAL]
# 	223 : JointEnergy [NUMERICAL]
# 	200 : JointEntropy [NUMERICAL]
# 	197 : SumSquares [NUMERICAL]
# 	185 : ClusterTendency [NUMERICAL]
#
# Condition type in nodes:
# 	32945 : HigherCondition
# Condition type in nodes with depth <= 0:
# 	300 : HigherCondition
# Condition type in nodes with depth <= 1:
# 	897 : HigherCondition
# Condition type in nodes with depth <= 2:
# 	2030 : HigherCondition
# Condition type in nodes with depth <= 3:
# 	3977 : HigherCondition
# Condition type in nodes with depth <= 5:
# 	10633 : HigherCondition
# Node format: NOT_SET
#
# Training OOB:
# 	trees: 1, Out-of-bag evaluation: accuracy:0.841757 logloss:5.70366
# 	trees: 11, Out-of-bag evaluation: accuracy:0.841717 logloss:2.4611
# 	trees: 21, Out-of-bag evaluation: accuracy:0.855543 logloss:1.77608
# 	trees: 31, Out-of-bag evaluation: accuracy:0.863316 logloss:1.13023
# 	trees: 41, Out-of-bag evaluation: accuracy:0.863208 logloss:0.990744
# 	trees: 51, Out-of-bag evaluation: accuracy:0.863488 logloss:0.789411
# 	trees: 61, Out-of-bag evaluation: accuracy:0.867289 logloss:0.714533
# 	trees: 71, Out-of-bag evaluation: accuracy:0.865319 logloss:0.577032
# 	trees: 81, Out-of-bag evaluation: accuracy:0.869681 logloss:0.57735
# 	trees: 91, Out-of-bag evaluation: accuracy:0.870842 logloss:0.576484
# 	trees: 101, Out-of-bag evaluation: accuracy:0.876014 logloss:0.544652
# 	trees: 111, Out-of-bag evaluation: accuracy:0.873763 logloss:0.542298
# 	trees: 121, Out-of-bag evaluation: accuracy:0.870631 logloss:0.542247
# 	trees: 131, Out-of-bag evaluation: accuracy:0.872672 logloss:0.541936
# 	trees: 141, Out-of-bag evaluation: accuracy:0.872602 logloss:0.54131
# 	trees: 151, Out-of-bag evaluation: accuracy:0.873763 logloss:0.543626
# 	trees: 161, Out-of-bag evaluation: accuracy:0.873692 logloss:0.512043
# 	trees: 171, Out-of-bag evaluation: accuracy:0.871722 logloss:0.510192
# 	trees: 181, Out-of-bag evaluation: accuracy:0.872672 logloss:0.477597
# 	trees: 191, Out-of-bag evaluation: accuracy:0.873833 logloss:0.478105
# 	trees: 201, Out-of-bag evaluation: accuracy:0.874853 logloss:0.443519
# 	trees: 211, Out-of-bag evaluation: accuracy:0.873833 logloss:0.409864
# 	trees: 221, Out-of-bag evaluation: accuracy:0.873903 logloss:0.409214
# 	trees: 231, Out-of-bag evaluation: accuracy:0.872882 logloss:0.410646
# 	trees: 241, Out-of-bag evaluation: accuracy:0.872953 logloss:0.410079
# 	trees: 251, Out-of-bag evaluation: accuracy:0.876084 logloss:0.409413
# 	trees: 261, Out-of-bag evaluation: accuracy:0.873973 logloss:0.409312
# 	trees: 271, Out-of-bag evaluation: accuracy:0.873973 logloss:0.409117
# 	trees: 281, Out-of-bag evaluation: accuracy:0.874994 logloss:0.408406
# 	trees: 291, Out-of-bag evaluation: accuracy:0.874994 logloss:0.376677
# 	trees: 300, Out-of-bag evaluation: accuracy:0.874113 logloss:0.344915

# %%
# Model features
model.make_inspector().features()
# Out:
# ["Autocorrelation" (1; #0),
#  "ClusterProminence" (1; #1),
#  "ClusterShade" (1; #2),
#  "ClusterTendency" (1; #3),
#  "Contrast" (1; #4),
#  "Correlation" (1; #5),
#  "DifferenceAverage" (1; #6),
#  "DifferenceEntropy" (1; #7),
#  "DifferenceVariance" (1; #8),
#  "Id" (1; #9),
#  "Idm" (1; #10),
#  "Idmn" (1; #11),
#  "Idn" (1; #12),
#  "Imc1" (1; #13),
#  "Imc2" (1; #14),
#  "InverseVariance" (1; #15),
#  "JointAverage" (1; #16),
#  "JointEnergy" (1; #17),
#  "JointEntropy" (1; #18),
#  "MCC" (1; #19),
#  "MaximumProbability" (1; #20),
#  "SumAverage" (1; #21),
#  "SumEntropy" (1; #22),
#  "SumSquares" (1; #23)]

# %%
# Feature importance
model.make_inspector().variable_importances()
# Out:
# {'INV_MEAN_MIN_DEPTH': [("Autocorrelation" (1; #0), 0.19463020758861158),
#   ("JointAverage" (1; #16), 0.18877548723517742),
#   ("SumAverage" (1; #21), 0.17695841589699338),
#   ("InverseVariance" (1; #15), 0.13372689338131696),
#   ("Correlation" (1; #5), 0.131770554581309),
#   ("SumEntropy" (1; #22), 0.1252497302294797),
#   ("Idn" (1; #12), 0.12287863588515922),
#   ("Imc1" (1; #13), 0.12280517684488841),
#   ("Idm" (1; #10), 0.12262329536819398),
#   ("MCC" (1; #19), 0.12196001949496399),
#   ("Idmn" (1; #11), 0.12119878970473373),
#   ("Id" (1; #9), 0.11786343270358571),
#   ("DifferenceEntropy" (1; #7), 0.11693669361218029),
#   ("MaximumProbability" (1; #20), 0.11668078763514826),
#   ("ClusterShade" (1; #2), 0.1166715492328943),
#   ("DifferenceAverage" (1; #6), 0.11640382562535176),
#   ("Imc2" (1; #14), 0.11580692165040533),
#   ("JointEnergy" (1; #17), 0.1142840209149537),
#   ("JointEntropy" (1; #18), 0.11347351153085905),
#   ("Contrast" (1; #4), 0.1125420885759175),
#   ("DifferenceVariance" (1; #8), 0.11181511521551574),
#   ("ClusterProminence" (1; #1), 0.10986319042664004),
#   ("SumSquares" (1; #23), 0.10779719425403435),
#   ("ClusterTendency" (1; #3), 0.10774835098364505)],
#  'NUM_AS_ROOT': [("Autocorrelation" (1; #0), 66.0),
#   ("JointAverage" (1; #16), 60.0),
#   ("SumAverage" (1; #21), 54.0),
#   ("SumEntropy" (1; #22), 36.0),
#   ("Correlation" (1; #5), 17.0),
#   ("JointEntropy" (1; #18), 17.0),
#   ("MCC" (1; #19), 14.0),
#   ("JointEnergy" (1; #17), 10.0),
#   ("Imc1" (1; #13), 9.0),
#   ("Imc2" (1; #14), 8.0),
#   ("MaximumProbability" (1; #20), 8.0),
#   ("ClusterProminence" (1; #1), 1.0)],
#  'SUM_SCORE': [("Autocorrelation" (1; #0), 286970.57755398564),
#   ("JointAverage" (1; #16), 272211.72928176896),
#   ("SumAverage" (1; #21), 246983.7811196218),
#   ("Idn" (1; #12), 75256.629439549),
#   ("Idmn" (1; #11), 66732.80515788408),
#   ("InverseVariance" (1; #15), 59242.249230015754),
#   ("Correlation" (1; #5), 44312.410098378976),
#   ("Idm" (1; #10), 38861.891887527),
#   ("Imc1" (1; #13), 36746.219765703514),
#   ("SumEntropy" (1; #22), 35707.14389119278),
#   ("ClusterShade" (1; #2), 34508.90814274763),
#   ("Id" (1; #9), 32101.405162600167),
#   ("MCC" (1; #19), 31132.845906271865),
#   ("DifferenceEntropy" (1; #7), 30637.50408053819),
#   ("DifferenceAverage" (1; #6), 30178.40932611153),
#   ("MaximumProbability" (1; #20), 27293.73118241103),
#   ("Imc2" (1; #14), 26899.313485696523),
#   ("Contrast" (1; #4), 25652.224398574355),
#   ("DifferenceVariance" (1; #8), 24626.96234477751),
#   ("JointEnergy" (1; #17), 23716.5904727045),
#   ("JointEntropy" (1; #18), 20953.142781163642),
#   ("ClusterProminence" (1; #1), 19727.378262163347),
#   ("ClusterTendency" (1; #3), 15386.096910321516),
#   ("SumSquares" (1; #23), 15378.100944644972)],
#  'NUM_NODES': [("Idn" (1; #12), 2602.0),
#   ("Idmn" (1; #11), 2205.0),
#   ("JointAverage" (1; #16), 2107.0),
#   ("Autocorrelation" (1; #0), 2085.0),
#   ("SumAverage" (1; #21), 2008.0),
#   ("ClusterShade" (1; #2), 1694.0),
#   ("Correlation" (1; #5), 1537.0),
#   ("InverseVariance" (1; #15), 1435.0),
#   ("Imc1" (1; #13), 1297.0),
#   ("MCC" (1; #19), 1227.0),
#   ("DifferenceVariance" (1; #8), 1220.0),
#   ("Contrast" (1; #4), 1198.0),
#   ("DifferenceAverage" (1; #6), 1155.0),
#   ("DifferenceEntropy" (1; #7), 1146.0),
#   ("Idm" (1; #10), 1142.0),
#   ("SumEntropy" (1; #22), 1128.0),
#   ("MaximumProbability" (1; #20), 1092.0),
#   ("Imc2" (1; #14), 1091.0),
#   ("Id" (1; #9), 1056.0),
#   ("ClusterProminence" (1; #1), 1044.0),
#   ("JointEnergy" (1; #17), 931.0),
#   ("JointEntropy" (1; #18), 885.0),
#   ("SumSquares" (1; #23), 856.0),
#   ("ClusterTendency" (1; #3), 804.0)]}

# %%
# Model self evaluation
model.make_inspector().evaluation()
# Out:
# Evaluation(num_examples=7617, accuracy=0.8741133894519209, loss=0.34491533048842615, rmse=None, ndcg=None, aucs=None, auuc=None, qini=None)

# %%
logs = model.make_inspector().training_logs()

plt.figure(figsize=(12, 4))
plt.subplot(1, 2, 1)
plt.plot([log.num_trees for log in logs], [log.evaluation.accuracy for log in logs])
plt.xlabel("Number of trees")
plt.ylabel("Accuracy (out-of-bag)")
plt.subplot(1, 2, 2)
plt.plot([log.num_trees for log in logs], [log.evaluation.loss for log in logs])
plt.xlabel("Number of trees")
plt.ylabel("Logloss (out-of-bag)")
plt.show()

# %% [markdown]
# Calculate the score of our hold-out validation dataset

# %%
predictions = model.predict(val_ds)
y_true      = validation_data["label"]

from sklearn.metrics import roc_auc_score
ROC_AUC = roc_auc_score(y_true, predictions)
print("The ROC AUC score is %.5f" % ROC_AUC )
# Out:
# 1/2 [==============>...............] - ETA: 0s
# 2/2 [==============================] - 0s 3ms/step
# The ROC AUC score is 0.99864

# %%
# Compute binary classification metrics with sklearn
import numpy as np
from sklearn.metrics import (
    accuracy_score,
    precision_score,
    recall_score,
    f1_score,
    roc_auc_score,
    average_precision_score,
    confusion_matrix,
    classification_report,
    matthews_corrcoef,
    log_loss,
    brier_score_loss,
)

# Get predictions (probabilities or class labels)
preds = model.predict(test_ds)
# If model outputs probabilities, convert to labels by threshold 0.5
if preds.ndim == 2:
    # For TFDF classification, preds may be class probabilities with shape (N, 2)
    if preds.shape[1] == 2:
        pos_probs = preds[:, 1]
    else:
        # If single-probability column (positive class)
        pos_probs = preds[:, -1]
    y_pred = (pos_probs >= 0.5).astype(int)
else:
    # Already class labels
    y_pred = preds.astype(int)
    pos_probs = None

# Ground truth labels (must be 0/1 integers)
y_true = test_data["label"].astype(int).to_numpy()

# Core metrics
metrics = {}
metrics["accuracy"] = accuracy_score(y_true, y_pred)
metrics["precision"] = precision_score(y_true, y_pred, zero_division=0)
metrics["recall"] = recall_score(y_true, y_pred, zero_division=0)
metrics["f1"] = f1_score(y_true, y_pred, zero_division=0)
metrics["mcc"] = matthews_corrcoef(y_true, y_pred)

# Probabilistic metrics (only if we have probabilities)
if pos_probs is not None:
    metrics["roc_auc"] = roc_auc_score(y_true, pos_probs)
    metrics["pr_auc"] = average_precision_score(y_true, pos_probs)
    metrics["log_loss"] = log_loss(y_true, pos_probs, labels=[0,1])
    metrics["brier_score"] = brier_score_loss(y_true, pos_probs)

# Confusion matrix and detailed report
cm = confusion_matrix(y_true, y_pred, labels=[0,1])
report = classification_report(y_true, y_pred, digits=4)

print("Sklearn binary metrics:")
for k, v in metrics.items():
    print(f"{k}: {v:.4f}")
print("\nConfusion matrix:\n", cm)
print("\nClassification report:\n", report)
# Out:
# 1/3 [=========>....................] - ETA: 0s
# 3/3 [==============================] - 0s 10ms/step
# Sklearn binary metrics:
# accuracy: 0.9676
# precision: 0.9005
# recall: 0.7577
# f1: 0.8230
# mcc: 0.8089
# roc_auc: 0.9735
# pr_auc: 0.8821
# log_loss: 0.1072
# brier_score: 0.0269
#
# Confusion matrix:
#  [[2037   19]
#  [  55  172]]
#
# Classification report:
#                precision    recall  f1-score   support
#
#            0     0.9737    0.9908    0.9822      2056
#            1     0.9005    0.7577    0.8230       227
#
#     accuracy                         0.9676      2283
#    macro avg     0.9371    0.8742    0.9026      2283
# weighted avg     0.9664    0.9676    0.9663      2283
