# %%
# Import packages and modules
import numpy  as np
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow_decision_forests as tfdf

from sklearn.model_selection import train_test_split
# Out:
# 2026-09-12 10:42:46.042105: I tensorflow/core/util/port.cc:113] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2026-09-12 10:42:46.395232: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2026-09-12 10:42:51.068025: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
# Check the version of TensorFlow Decision Forests
print("Found TensorFlow Decision Forests v" + tfdf.__version__)
# Out:
# Found TensorFlow Decision Forests v1.9.1

# %%
datasetPath = "dataset/10p/all/kernel3/"

# %%
# Parameters
datasetPath = "dataset/mask5/10p/glrlm/kernel4/"

# %%
# train/validation/test = 70/10/20
train_data = pd.read_csv(f"{datasetPath}dataset.train.csv")
validation_data = pd.read_csv(f"{datasetPath}dataset.validation.csv")
test_data = pd.read_csv(f"{datasetPath}dataset.test.csv")

# %%
from sklearn.utils.class_weight import compute_class_weight

# tinh class weight tren tap train
classes = np.array([0, 1])
weights = compute_class_weight(class_weight="balanced", classes=classes, y=train_data["label"])
class_weight = {0: weights[0], 1: weights[1]}

# gan sample_weight cho tung dong
train_data["sample_weight"] = train_data["label"].map(class_weight)
validation_data["sample_weight"] = validation_data["label"].map(class_weight)
test_data["sample_weight"] = test_data["label"].map(class_weight)

# Convert the dataset into a TensorFlow dataset.
train_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    train_data, label="label", weight="sample_weight"
)         
val_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    validation_data, label="label", weight="sample_weight"
)
test_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    test_data, label="label", weight="sample_weight"
)
# Out:
# 2026-09-12 10:43:03.486213: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:984] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2026-09-12 10:43:03.488001: W tensorflow/core/common_runtime/gpu/gpu_device.cc:2251] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...

# %%
import keras

# %%
# %%time

# Train a Random Forest model.
model = tfdf.keras.RandomForestModel()

# Add evaluation metrics
model.compile(
    metrics=["accuracy"]
)
model.fit(x=train_ds)

# # Train a Gradient Boosted Trees model.
# model = tfdf.keras.GradientBoostedTreesModel(num_trees=1500)
# model.fit(train_ds)
# Out:
# Use /tmp/tmp7dwms_e5 as temporary training directory
# Reading training dataset...
# Training dataset read in 0:00:02.626070. Found 7617 examples.
# Training model...
# Model trained in 0:00:00.510887
# Compiling model...
# [INFO 26-09-12 10:43:06.6910 UTC kernel.cc:1233] Loading model from path /tmp/tmp7dwms_e5/model/ with prefix 995f2503ff7f4c0c
# [INFO 26-09-12 10:43:06.7857 UTC decision_forest.cc:734] Model loaded with 300 root(s), 77294 node(s), and 16 input feature(s).
# [INFO 26-09-12 10:43:06.7857 UTC abstract_model.cc:1362] Engine "RandomForestOptPred" built
# [INFO 26-09-12 10:43:06.7857 UTC kernel.cc:1061] Use fast generic engine
# Model compiled.
# CPU times: user 9.24 s, sys: 172 ms, total: 9.41 s
# Wall time: 6.23 s

# %%
# Evaluate the model
evaluate = model.evaluate(val_ds, return_dict=True)
print()

for name, value in evaluate.items():
    print(f"{name}: {value:.4f}")
# Out:
# WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 1/2 [==============>...............] - ETA: 3s - loss: 0.0000e+00 - accuracy: 0.9850
# 2/2 [==============================] - 4s 8ms/step - loss: 0.0000e+00 - accuracy: 0.9861
# loss: 0.0000
# accuracy: 0.9861

# %%
# Model Summary
model.summary()
# Out:
# Model: "random_forest_model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
# =================================================================
# Total params: 1 (1.00 Byte)
# Trainable params: 0 (0.00 Byte)
# Non-trainable params: 1 (1.00 Byte)
# _________________________________________________________________
# Type: "RANDOM_FOREST"
# Task: CLASSIFICATION
# Label: "__LABEL"
#
# Input Features (16):
# 	GrayLevelNonUniformity
# 	GrayLevelNonUniformityNormalized
# 	GrayLevelVariance
# 	HighGrayLevelRunEmphasis
# 	LongRunEmphasis
# 	LongRunHighGrayLevelEmphasis
# 	LongRunLowGrayLevelEmphasis
# 	LowGrayLevelRunEmphasis
# 	RunEntropy
# 	RunLengthNonUniformity
# 	RunLengthNonUniformityNormalized
# 	RunPercentage
# 	RunVariance
# 	ShortRunEmphasis
# 	ShortRunHighGrayLevelEmphasis
# 	ShortRunLowGrayLevelEmphasis
#
# Trained with weights
#
# Variable Importance: INV_MEAN_MIN_DEPTH:
#     1.     "LongRunHighGrayLevelEmphasis"  0.268504 ################
#     2.         "HighGrayLevelRunEmphasis"  0.164270 #####
#     3.    "ShortRunHighGrayLevelEmphasis"  0.155072 ####
#     4.          "LowGrayLevelRunEmphasis"  0.147065 ###
#     5.      "LongRunLowGrayLevelEmphasis"  0.140728 ##
#     6.     "ShortRunLowGrayLevelEmphasis"  0.139374 ##
#     7.                       "RunEntropy"  0.127859 #
#     8.                      "RunVariance"  0.123987 #
#     9.           "GrayLevelNonUniformity"  0.121727
#    10.                  "LongRunEmphasis"  0.121361
#    11. "GrayLevelNonUniformityNormalized"  0.118169
#    12.                "GrayLevelVariance"  0.116169
#    13. "RunLengthNonUniformityNormalized"  0.115493
#    14.                 "ShortRunEmphasis"  0.114088
#    15.                    "RunPercentage"  0.113641
#    16.           "RunLengthNonUniformity"  0.112600
#
# Variable Importance: NUM_AS_ROOT:
#     1.     "LongRunHighGrayLevelEmphasis" 101.000000 ################
#     2.         "HighGrayLevelRunEmphasis" 54.000000 ########
#     3.    "ShortRunHighGrayLevelEmphasis" 53.000000 ########
#     4.     "ShortRunLowGrayLevelEmphasis" 41.000000 ######
#     5.          "LowGrayLevelRunEmphasis" 26.000000 ####
#     6.      "LongRunLowGrayLevelEmphasis" 14.000000 ##
#     7. "GrayLevelNonUniformityNormalized"  5.000000
#     8.           "GrayLevelNonUniformity"  2.000000
#     9.                       "RunEntropy"  2.000000
#    10.                  "LongRunEmphasis"  1.000000
#    11.                      "RunVariance"  1.000000
#
# Variable Importance: NUM_NODES:
#     1.     "LongRunHighGrayLevelEmphasis" 3453.000000 ################
#     2.                       "RunEntropy" 3132.000000 #############
#     3.           "GrayLevelNonUniformity" 2884.000000 ##########
#     4.                "GrayLevelVariance" 2843.000000 ##########
#     5. "GrayLevelNonUniformityNormalized" 2687.000000 ########
#     6.    "ShortRunHighGrayLevelEmphasis" 2508.000000 #######
#     7.          "LowGrayLevelRunEmphasis" 2500.000000 #######
#     8.     "ShortRunLowGrayLevelEmphasis" 2499.000000 #######
#     9.         "HighGrayLevelRunEmphasis" 2451.000000 ######
#    10.      "LongRunLowGrayLevelEmphasis" 2428.000000 ######
#    11.                      "RunVariance" 2179.000000 ####
#    12.                  "LongRunEmphasis" 1890.000000 #
#    13. "RunLengthNonUniformityNormalized" 1822.000000 #
#    14.           "RunLengthNonUniformity" 1779.000000
#    15.                 "ShortRunEmphasis" 1736.000000
#    16.                    "RunPercentage" 1706.000000
#
# Variable Importance: SUM_SCORE:
#     1.     "LongRunHighGrayLevelEmphasis" 366751.591308 ################
#     2.         "HighGrayLevelRunEmphasis" 180755.313218 #######
#     3.    "ShortRunHighGrayLevelEmphasis" 172720.001817 ######
#     4.     "ShortRunLowGrayLevelEmphasis" 125286.683024 ####
#     5.          "LowGrayLevelRunEmphasis" 110427.602961 ###
#     6.      "LongRunLowGrayLevelEmphasis" 82235.824005 ##
#     7.                       "RunEntropy" 73937.901791 #
#     8.           "GrayLevelNonUniformity" 56917.617927 #
#     9. "GrayLevelNonUniformityNormalized" 53315.418676
#    10.                "GrayLevelVariance" 50411.470764
#    11.                      "RunVariance" 47674.748641
#    12.                  "LongRunEmphasis" 43495.679359
#    13. "RunLengthNonUniformityNormalized" 37058.142110
#    14.                 "ShortRunEmphasis" 33664.376320
#    15.           "RunLengthNonUniformity" 33488.080772
#    16.                    "RunPercentage" 33007.878031
#
#
#
# Winner takes all: true
# Out-of-bag evaluation: accuracy:0.853616 logloss:0.647081
# Number of trees: 300
# Total number of nodes: 77294
#
# Number of nodes by tree:
# Count: 300 Average: 257.647 StdDev: 14.4894
# Min: 223 Max: 303 Ignored: 0
# ----------------------------------------------
# [ 223, 227)  4   1.33%   1.33% #
# [ 227, 231)  8   2.67%   4.00% ##
# [ 231, 235)  6   2.00%   6.00% ##
# [ 235, 239) 10   3.33%   9.33% ###
# [ 239, 243) 11   3.67%  13.00% ###
# [ 243, 247) 19   6.33%  19.33% #####
# [ 247, 251) 31  10.33%  29.67% ########
# [ 251, 255) 38  12.67%  42.33% ##########
# [ 255, 259) 35  11.67%  54.00% #########
# [ 259, 263) 25   8.33%  62.33% #######
# [ 263, 267) 26   8.67%  71.00% #######
# [ 267, 271) 20   6.67%  77.67% #####
# [ 271, 275) 26   8.67%  86.33% #######
# [ 275, 279) 18   6.00%  92.33% #####
# [ 279, 283) 10   3.33%  95.67% ###
# [ 283, 287)  3   1.00%  96.67% #
# [ 287, 291)  9   3.00%  99.67% ##
# [ 291, 295)  0   0.00%  99.67%
# [ 295, 299)  0   0.00%  99.67%
# [ 299, 303]  1   0.33% 100.00%
#
# Depth by leafs:
# Count: 38797 Average: 9.22149 StdDev: 2.65611
# Min: 2 Max: 15 Ignored: 0
# ----------------------------------------------
# [  2,  3)   55   0.14%   0.14%
# [  3,  4)  461   1.19%   1.33% #
# [  4,  5)  892   2.30%   3.63% ##
# [  5,  6) 1737   4.48%   8.11% ###
# [  6,  7) 2860   7.37%  15.48% #####
# [  7,  8) 4328  11.16%  26.63% ########
# [  8,  9) 5281  13.61%  40.25% #########
# [  9, 10) 5655  14.58%  54.82% ##########
# [ 10, 11) 5161  13.30%  68.12% #########
# [ 11, 12) 4439  11.44%  79.57% ########
# [ 12, 13) 3417   8.81%  88.37% ######
# [ 13, 14) 2194   5.66%  94.03% ####
# [ 14, 15) 1299   3.35%  97.38% ##
# [ 15, 15] 1018   2.62% 100.00% ##
#
# Number of training obs by leaf:
# Count: 38797 Average: 58.8989 StdDev: 183.721
# Min: 5 Max: 2315 Ignored: 0
# ----------------------------------------------
# [    5,  120) 35155  90.61%  90.61% ##########
# [  120,  236)  1446   3.73%  94.34%
# [  236,  351)   539   1.39%  95.73%
# [  351,  467)   353   0.91%  96.64%
# [  467,  582)   267   0.69%  97.33%
# [  582,  698)   228   0.59%  97.91%
# [  698,  813)   140   0.36%  98.28%
# [  813,  929)    96   0.25%  98.52%
# [  929, 1044)   149   0.38%  98.91%
# [ 1044, 1160)   112   0.29%  99.20%
# [ 1160, 1276)    84   0.22%  99.41%
# [ 1276, 1391)    58   0.15%  99.56%
# [ 1391, 1507)    65   0.17%  99.73%
# [ 1507, 1622)    42   0.11%  99.84%
# [ 1622, 1738)    25   0.06%  99.90%
# [ 1738, 1853)    15   0.04%  99.94%
# [ 1853, 1969)    11   0.03%  99.97%
# [ 1969, 2084)     5   0.01%  99.98%
# [ 2084, 2200)     4   0.01%  99.99%
# [ 2200, 2315]     3   0.01% 100.00%
#
# Attribute in nodes:
# 	3453 : LongRunHighGrayLevelEmphasis [NUMERICAL]
# 	3132 : RunEntropy [NUMERICAL]
# 	2884 : GrayLevelNonUniformity [NUMERICAL]
# 	2843 : GrayLevelVariance [NUMERICAL]
# 	2687 : GrayLevelNonUniformityNormalized [NUMERICAL]
# 	2508 : ShortRunHighGrayLevelEmphasis [NUMERICAL]
# 	2500 : LowGrayLevelRunEmphasis [NUMERICAL]
# 	2499 : ShortRunLowGrayLevelEmphasis [NUMERICAL]
# 	2451 : HighGrayLevelRunEmphasis [NUMERICAL]
# 	2428 : LongRunLowGrayLevelEmphasis [NUMERICAL]
# 	2179 : RunVariance [NUMERICAL]
# 	1890 : LongRunEmphasis [NUMERICAL]
# 	1822 : RunLengthNonUniformityNormalized [NUMERICAL]
# 	1779 : RunLengthNonUniformity [NUMERICAL]
# 	1736 : ShortRunEmphasis [NUMERICAL]
# 	1706 : RunPercentage [NUMERICAL]
#
# Attribute in nodes with depth <= 0:
# 	101 : LongRunHighGrayLevelEmphasis [NUMERICAL]
# 	54 : HighGrayLevelRunEmphasis [NUMERICAL]
# 	53 : ShortRunHighGrayLevelEmphasis [NUMERICAL]
# 	41 : ShortRunLowGrayLevelEmphasis [NUMERICAL]
# 	26 : LowGrayLevelRunEmphasis [NUMERICAL]
# 	14 : LongRunLowGrayLevelEmphasis [NUMERICAL]
# 	5 : GrayLevelNonUniformityNormalized [NUMERICAL]
# 	2 : RunEntropy [NUMERICAL]
# 	2 : GrayLevelNonUniformity [NUMERICAL]
# 	1 : RunVariance [NUMERICAL]
# 	1 : LongRunEmphasis [NUMERICAL]
#
# Attribute in nodes with depth <= 1:
# 	272 : LongRunHighGrayLevelEmphasis [NUMERICAL]
# 	170 : HighGrayLevelRunEmphasis [NUMERICAL]
# 	118 : ShortRunHighGrayLevelEmphasis [NUMERICAL]
# 	102 : LowGrayLevelRunEmphasis [NUMERICAL]
# 	90 : ShortRunLowGrayLevelEmphasis [NUMERICAL]
# 	87 : LongRunLowGrayLevelEmphasis [NUMERICAL]
# 	14 : GrayLevelNonUniformity [NUMERICAL]
# 	13 : RunVariance [NUMERICAL]
# 	13 : GrayLevelNonUniformityNormalized [NUMERICAL]
# 	8 : RunEntropy [NUMERICAL]
# 	7 : LongRunEmphasis [NUMERICAL]
# 	4 : ShortRunEmphasis [NUMERICAL]
# 	1 : RunPercentage [NUMERICAL]
# 	1 : RunLengthNonUniformityNormalized [NUMERICAL]
#
# Attribute in nodes with depth <= 2:
# 	486 : LongRunHighGrayLevelEmphasis [NUMERICAL]
# 	247 : HighGrayLevelRunEmphasis [NUMERICAL]
# 	196 : LowGrayLevelRunEmphasis [NUMERICAL]
# 	195 : ShortRunHighGrayLevelEmphasis [NUMERICAL]
# 	177 : LongRunLowGrayLevelEmphasis [NUMERICAL]
# 	157 : ShortRunLowGrayLevelEmphasis [NUMERICAL]
# 	90 : LongRunEmphasis [NUMERICAL]
# 	84 : RunVariance [NUMERICAL]
# 	81 : GrayLevelNonUniformityNormalized [NUMERICAL]
# 	71 : GrayLevelNonUniformity [NUMERICAL]
# 	59 : RunEntropy [NUMERICAL]
# 	51 : RunLengthNonUniformityNormalized [NUMERICAL]
# 	49 : RunPercentage [NUMERICAL]
# 	44 : ShortRunEmphasis [NUMERICAL]
# 	30 : RunLengthNonUniformity [NUMERICAL]
# 	28 : GrayLevelVariance [NUMERICAL]
#
# Attribute in nodes with depth <= 3:
# 	682 : LongRunHighGrayLevelEmphasis [NUMERICAL]
# 	390 : HighGrayLevelRunEmphasis [NUMERICAL]
# 	349 : LowGrayLevelRunEmphasis [NUMERICAL]
# 	347 : ShortRunHighGrayLevelEmphasis [NUMERICAL]
# 	274 : LongRunLowGrayLevelEmphasis [NUMERICAL]
# 	256 : ShortRunLowGrayLevelEmphasis [NUMERICAL]
# 	204 : GrayLevelNonUniformityNormalized [NUMERICAL]
# 	200 : RunVariance [NUMERICAL]
# 	200 : LongRunEmphasis [NUMERICAL]
# 	198 : GrayLevelNonUniformity [NUMERICAL]
# 	189 : RunEntropy [NUMERICAL]
# 	153 : GrayLevelVariance [NUMERICAL]
# 	117 : RunPercentage [NUMERICAL]
# 	112 : RunLengthNonUniformityNormalized [NUMERICAL]
# 	106 : RunLengthNonUniformity [NUMERICAL]
# 	97 : ShortRunEmphasis [NUMERICAL]
#
# Attribute in nodes with depth <= 5:
# 	1188 : LongRunHighGrayLevelEmphasis [NUMERICAL]
# 	795 : RunEntropy [NUMERICAL]
# 	785 : LowGrayLevelRunEmphasis [NUMERICAL]
# 	776 : HighGrayLevelRunEmphasis [NUMERICAL]
# 	758 : ShortRunHighGrayLevelEmphasis [NUMERICAL]
# 	732 : GrayLevelNonUniformity [NUMERICAL]
# 	698 : ShortRunLowGrayLevelEmphasis [NUMERICAL]
# 	668 : GrayLevelNonUniformityNormalized [NUMERICAL]
# 	667 : LongRunLowGrayLevelEmphasis [NUMERICAL]
# 	648 : GrayLevelVariance [NUMERICAL]
# 	590 : RunVariance [NUMERICAL]
# 	524 : LongRunEmphasis [NUMERICAL]
# 	426 : RunLengthNonUniformity [NUMERICAL]
# 	408 : RunLengthNonUniformityNormalized [NUMERICAL]
# 	394 : RunPercentage [NUMERICAL]
# 	378 : ShortRunEmphasis [NUMERICAL]
#
# Condition type in nodes:
# 	38497 : HigherCondition
# Condition type in nodes with depth <= 0:
# 	300 : HigherCondition
# Condition type in nodes with depth <= 1:
# 	900 : HigherCondition
# Condition type in nodes with depth <= 2:
# 	2045 : HigherCondition
# Condition type in nodes with depth <= 3:
# 	3874 : HigherCondition
# Condition type in nodes with depth <= 5:
# 	10435 : HigherCondition
# Node format: NOT_SET
#
# Training OOB:
# 	trees: 1, Out-of-bag evaluation: accuracy:0.834186 logloss:5.97656
# 	trees: 11, Out-of-bag evaluation: accuracy:0.828055 logloss:2.77607
# 	trees: 21, Out-of-bag evaluation: accuracy:0.835746 logloss:1.81644
# 	trees: 31, Out-of-bag evaluation: accuracy:0.841549 logloss:1.36673
# 	trees: 41, Out-of-bag evaluation: accuracy:0.844292 logloss:1.12171
# 	trees: 51, Out-of-bag evaluation: accuracy:0.847493 logloss:1.01991
# 	trees: 61, Out-of-bag evaluation: accuracy:0.848654 logloss:0.84471
# 	trees: 71, Out-of-bag evaluation: accuracy:0.848724 logloss:0.779701
# 	trees: 81, Out-of-bag evaluation: accuracy:0.853826 logloss:0.77809
# 	trees: 91, Out-of-bag evaluation: accuracy:0.853826 logloss:0.746402
# 	trees: 101, Out-of-bag evaluation: accuracy:0.854847 logloss:0.747019
# 	trees: 111, Out-of-bag evaluation: accuracy:0.853896 logloss:0.746655
# 	trees: 121, Out-of-bag evaluation: accuracy:0.853756 logloss:0.744268
# 	trees: 131, Out-of-bag evaluation: accuracy:0.854636 logloss:0.743311
# 	trees: 141, Out-of-bag evaluation: accuracy:0.853686 logloss:0.711166
# 	trees: 151, Out-of-bag evaluation: accuracy:0.855446 logloss:0.678853
# 	trees: 161, Out-of-bag evaluation: accuracy:0.855657 logloss:0.678786
# 	trees: 171, Out-of-bag evaluation: accuracy:0.854917 logloss:0.679665
# 	trees: 181, Out-of-bag evaluation: accuracy:0.854706 logloss:0.678167
# 	trees: 191, Out-of-bag evaluation: accuracy:0.852736 logloss:0.677204
# 	trees: 201, Out-of-bag evaluation: accuracy:0.853686 logloss:0.678327
# 	trees: 211, Out-of-bag evaluation: accuracy:0.853616 logloss:0.677715
# 	trees: 221, Out-of-bag evaluation: accuracy:0.853896 logloss:0.677453
# 	trees: 231, Out-of-bag evaluation: accuracy:0.854917 logloss:0.678661
# 	trees: 241, Out-of-bag evaluation: accuracy:0.853686 logloss:0.678505
# 	trees: 252, Out-of-bag evaluation: accuracy:0.853616 logloss:0.678775
# 	trees: 262, Out-of-bag evaluation: accuracy:0.852736 logloss:0.646718
# 	trees: 272, Out-of-bag evaluation: accuracy:0.852736 logloss:0.646415
# 	trees: 282, Out-of-bag evaluation: accuracy:0.853686 logloss:0.645919
# 	trees: 292, Out-of-bag evaluation: accuracy:0.853546 logloss:0.646113
# 	trees: 300, Out-of-bag evaluation: accuracy:0.853616 logloss:0.647081

# %%
# Model features
model.make_inspector().features()
# Out:
# ["GrayLevelNonUniformity" (1; #0),
#  "GrayLevelNonUniformityNormalized" (1; #1),
#  "GrayLevelVariance" (1; #2),
#  "HighGrayLevelRunEmphasis" (1; #3),
#  "LongRunEmphasis" (1; #4),
#  "LongRunHighGrayLevelEmphasis" (1; #5),
#  "LongRunLowGrayLevelEmphasis" (1; #6),
#  "LowGrayLevelRunEmphasis" (1; #7),
#  "RunEntropy" (1; #8),
#  "RunLengthNonUniformity" (1; #9),
#  "RunLengthNonUniformityNormalized" (1; #10),
#  "RunPercentage" (1; #11),
#  "RunVariance" (1; #12),
#  "ShortRunEmphasis" (1; #13),
#  "ShortRunHighGrayLevelEmphasis" (1; #14),
#  "ShortRunLowGrayLevelEmphasis" (1; #15)]

# %%
# Feature importance
model.make_inspector().variable_importances()
# Out:
# {'INV_MEAN_MIN_DEPTH': [("LongRunHighGrayLevelEmphasis" (1; #5),
#    0.26850353664594007),
#   ("HighGrayLevelRunEmphasis" (1; #3), 0.1642703192342823),
#   ("ShortRunHighGrayLevelEmphasis" (1; #14), 0.1550716974177639),
#   ("LowGrayLevelRunEmphasis" (1; #7), 0.147065476223993),
#   ("LongRunLowGrayLevelEmphasis" (1; #6), 0.14072755794183828),
#   ("ShortRunLowGrayLevelEmphasis" (1; #15), 0.13937353624183152),
#   ("RunEntropy" (1; #8), 0.12785938100625024),
#   ("RunVariance" (1; #12), 0.12398707078710969),
#   ("GrayLevelNonUniformity" (1; #0), 0.12172674643362298),
#   ("LongRunEmphasis" (1; #4), 0.12136064270264026),
#   ("GrayLevelNonUniformityNormalized" (1; #1), 0.11816939088869603),
#   ("GrayLevelVariance" (1; #2), 0.11616912651395785),
#   ("RunLengthNonUniformityNormalized" (1; #10), 0.11549284952362271),
#   ("ShortRunEmphasis" (1; #13), 0.114088147451039),
#   ("RunPercentage" (1; #11), 0.11364145513109926),
#   ("RunLengthNonUniformity" (1; #9), 0.11260006877741928)],
#  'SUM_SCORE': [("LongRunHighGrayLevelEmphasis" (1; #5), 366751.5913083411),
#   ("HighGrayLevelRunEmphasis" (1; #3), 180755.31321786565),
#   ("ShortRunHighGrayLevelEmphasis" (1; #14), 172720.00181652865),
#   ("ShortRunLowGrayLevelEmphasis" (1; #15), 125286.68302361856),
#   ("LowGrayLevelRunEmphasis" (1; #7), 110427.60296144152),
#   ("LongRunLowGrayLevelEmphasis" (1; #6), 82235.82400467806),
#   ("RunEntropy" (1; #8), 73937.90179147445),
#   ("GrayLevelNonUniformity" (1; #0), 56917.61792721003),
#   ("GrayLevelNonUniformityNormalized" (1; #1), 53315.4186762126),
#   ("GrayLevelVariance" (1; #2), 50411.47076403753),
#   ("RunVariance" (1; #12), 47674.74864112521),
#   ("LongRunEmphasis" (1; #4), 43495.679359177186),
#   ("RunLengthNonUniformityNormalized" (1; #10), 37058.142110009154),
#   ("ShortRunEmphasis" (1; #13), 33664.37631952741),
#   ("RunLengthNonUniformity" (1; #9), 33488.080772463596),
#   ("RunPercentage" (1; #11), 33007.87803083679)],
#  'NUM_AS_ROOT': [("LongRunHighGrayLevelEmphasis" (1; #5), 101.0),
#   ("HighGrayLevelRunEmphasis" (1; #3), 54.0),
#   ("ShortRunHighGrayLevelEmphasis" (1; #14), 53.0),
#   ("ShortRunLowGrayLevelEmphasis" (1; #15), 41.0),
#   ("LowGrayLevelRunEmphasis" (1; #7), 26.0),
#   ("LongRunLowGrayLevelEmphasis" (1; #6), 14.0),
#   ("GrayLevelNonUniformityNormalized" (1; #1), 5.0),
#   ("GrayLevelNonUniformity" (1; #0), 2.0),
#   ("RunEntropy" (1; #8), 2.0),
#   ("LongRunEmphasis" (1; #4), 1.0),
#   ("RunVariance" (1; #12), 1.0)],
#  'NUM_NODES': [("LongRunHighGrayLevelEmphasis" (1; #5), 3453.0),
#   ("RunEntropy" (1; #8), 3132.0),
#   ("GrayLevelNonUniformity" (1; #0), 2884.0),
#   ("GrayLevelVariance" (1; #2), 2843.0),
#   ("GrayLevelNonUniformityNormalized" (1; #1), 2687.0),
#   ("ShortRunHighGrayLevelEmphasis" (1; #14), 2508.0),
#   ("LowGrayLevelRunEmphasis" (1; #7), 2500.0),
#   ("ShortRunLowGrayLevelEmphasis" (1; #15), 2499.0),
#   ("HighGrayLevelRunEmphasis" (1; #3), 2451.0),
#   ("LongRunLowGrayLevelEmphasis" (1; #6), 2428.0),
#   ("RunVariance" (1; #12), 2179.0),
#   ("LongRunEmphasis" (1; #4), 1890.0),
#   ("RunLengthNonUniformityNormalized" (1; #10), 1822.0),
#   ("RunLengthNonUniformity" (1; #9), 1779.0),
#   ("ShortRunEmphasis" (1; #13), 1736.0),
#   ("RunPercentage" (1; #11), 1706.0)]}

# %%
# Model self evaluation
model.make_inspector().evaluation()
# Out:
# Evaluation(num_examples=7617, accuracy=0.8536157418668131, loss=0.6470806194391863, rmse=None, ndcg=None, aucs=None, auuc=None, qini=None)

# %%
logs = model.make_inspector().training_logs()

plt.figure(figsize=(12, 4))
plt.subplot(1, 2, 1)
plt.plot([log.num_trees for log in logs], [log.evaluation.accuracy for log in logs])
plt.xlabel("Number of trees")
plt.ylabel("Accuracy (out-of-bag)")
plt.subplot(1, 2, 2)
plt.plot([log.num_trees for log in logs], [log.evaluation.loss for log in logs])
plt.xlabel("Number of trees")
plt.ylabel("Logloss (out-of-bag)")
plt.show()

# %% [markdown]
# Calculate the score of our hold-out validation dataset

# %%
predictions = model.predict(val_ds)
y_true      = validation_data["label"]

from sklearn.metrics import roc_auc_score
ROC_AUC = roc_auc_score(y_true, predictions)
print("The ROC AUC score is %.5f" % ROC_AUC )
# Out:
# 1/2 [==============>...............] - ETA: 0s
# 2/2 [==============================] - 0s 3ms/step
# The ROC AUC score is 0.99747

# %%
# Compute binary classification metrics with sklearn
import numpy as np
from sklearn.metrics import (
    accuracy_score,
    precision_score,
    recall_score,
    f1_score,
    roc_auc_score,
    average_precision_score,
    confusion_matrix,
    classification_report,
    matthews_corrcoef,
    log_loss,
    brier_score_loss,
)

# Get predictions (probabilities or class labels)
preds = model.predict(test_ds)
# If model outputs probabilities, convert to labels by threshold 0.5
if preds.ndim == 2:
    # For TFDF classification, preds may be class probabilities with shape (N, 2)
    if preds.shape[1] == 2:
        pos_probs = preds[:, 1]
    else:
        # If single-probability column (positive class)
        pos_probs = preds[:, -1]
    y_pred = (pos_probs >= 0.5).astype(int)
else:
    # Already class labels
    y_pred = preds.astype(int)
    pos_probs = None

# Ground truth labels (must be 0/1 integers)
y_true = test_data["label"].astype(int).to_numpy()

# Core metrics
metrics = {}
metrics["accuracy"] = accuracy_score(y_true, y_pred)
metrics["precision"] = precision_score(y_true, y_pred, zero_division=0)
metrics["recall"] = recall_score(y_true, y_pred, zero_division=0)
metrics["f1"] = f1_score(y_true, y_pred, zero_division=0)
metrics["mcc"] = matthews_corrcoef(y_true, y_pred)

# Probabilistic metrics (only if we have probabilities)
if pos_probs is not None:
    metrics["roc_auc"] = roc_auc_score(y_true, pos_probs)
    metrics["pr_auc"] = average_precision_score(y_true, pos_probs)
    metrics["log_loss"] = log_loss(y_true, pos_probs, labels=[0,1])
    metrics["brier_score"] = brier_score_loss(y_true, pos_probs)

# Confusion matrix and detailed report
cm = confusion_matrix(y_true, y_pred, labels=[0,1])
report = classification_report(y_true, y_pred, digits=4)

print("Sklearn binary metrics:")
for k, v in metrics.items():
    print(f"{k}: {v:.4f}")
print("\nConfusion matrix:\n", cm)
print("\nClassification report:\n", report)
# Out:
# 1/3 [=========>....................] - ETA: 0s
# 3/3 [==============================] - 0s 9ms/step
# Sklearn binary metrics:
# accuracy: 0.9671
# precision: 0.8958
# recall: 0.7577
# f1: 0.8210
# mcc: 0.8065
# roc_auc: 0.9536
# pr_auc: 0.8543
# log_loss: 0.1472
# brier_score: 0.0278
#
# Confusion matrix:
#  [[2036   20]
#  [  55  172]]
#
# Classification report:
#                precision    recall  f1-score   support
#
#            0     0.9737    0.9903    0.9819      2056
#            1     0.8958    0.7577    0.8210       227
#
#     accuracy                         0.9671      2283
#    macro avg     0.9348    0.8740    0.9015      2283
# weighted avg     0.9660    0.9671    0.9659      2283
