# %%
# Import packages and modules
import numpy  as np
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow_decision_forests as tfdf

from sklearn.model_selection import train_test_split
# Out:
# 2026-09-12 10:43:21.446467: I tensorflow/core/util/port.cc:113] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2026-09-12 10:43:21.814920: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2026-09-12 10:43:26.643509: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
# Check the version of TensorFlow Decision Forests
print("Found TensorFlow Decision Forests v" + tfdf.__version__)
# Out:
# Found TensorFlow Decision Forests v1.9.1

# %%
datasetPath = "dataset/10p/all/kernel3/"

# %%
# Parameters
datasetPath = "dataset/mask5/10p/glszm/kernel4/"

# %%
# train/validation/test = 70/10/20
train_data = pd.read_csv(f"{datasetPath}dataset.train.csv")
validation_data = pd.read_csv(f"{datasetPath}dataset.validation.csv")
test_data = pd.read_csv(f"{datasetPath}dataset.test.csv")

# %%
from sklearn.utils.class_weight import compute_class_weight

# tinh class weight tren tap train
classes = np.array([0, 1])
weights = compute_class_weight(class_weight="balanced", classes=classes, y=train_data["label"])
class_weight = {0: weights[0], 1: weights[1]}

# gan sample_weight cho tung dong
train_data["sample_weight"] = train_data["label"].map(class_weight)
validation_data["sample_weight"] = validation_data["label"].map(class_weight)
test_data["sample_weight"] = test_data["label"].map(class_weight)

# Convert the dataset into a TensorFlow dataset.
train_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    train_data, label="label", weight="sample_weight"
)         
val_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    validation_data, label="label", weight="sample_weight"
)
test_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    test_data, label="label", weight="sample_weight"
)
# Out:
# 2026-09-12 10:43:39.144732: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:984] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2026-09-12 10:43:39.146265: W tensorflow/core/common_runtime/gpu/gpu_device.cc:2251] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...

# %%
import keras

# %%
# %%time

# Train a Random Forest model.
model = tfdf.keras.RandomForestModel()

# Add evaluation metrics
model.compile(
    metrics=["accuracy"]
)
model.fit(x=train_ds)

# # Train a Gradient Boosted Trees model.
# model = tfdf.keras.GradientBoostedTreesModel(num_trees=1500)
# model.fit(train_ds)
# Out:
# Use /tmp/tmpi4upl2nu as temporary training directory
# Reading training dataset...
# Training dataset read in 0:00:02.501931. Found 7617 examples.
# Training model...
# Model trained in 0:00:00.553465
# Compiling model...
# [INFO 26-09-12 10:43:42.2476 UTC kernel.cc:1233] Loading model from path /tmp/tmpi4upl2nu/model/ with prefix d30ff8eeefb84d48
# [INFO 26-09-12 10:43:42.3499 UTC decision_forest.cc:734] Model loaded with 300 root(s), 76976 node(s), and 16 input feature(s).
# [INFO 26-09-12 10:43:42.3499 UTC abstract_model.cc:1362] Engine "RandomForestOptPred" built
# [INFO 26-09-12 10:43:42.3500 UTC kernel.cc:1061] Use fast generic engine
# Model compiled.
# CPU times: user 9.67 s, sys: 171 ms, total: 9.84 s
# Wall time: 7.18 s

# %%
# Evaluate the model
evaluate = model.evaluate(val_ds, return_dict=True)
print()

for name, value in evaluate.items():
    print(f"{name}: {value:.4f}")
# Out:
# WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 1/2 [==============>...............] - ETA: 2s - loss: 0.0000e+00 - accuracy: 0.9890
# 2/2 [==============================] - 3s 8ms/step - loss: 0.0000e+00 - accuracy: 0.9898
# loss: 0.0000
# accuracy: 0.9898

# %%
# Model Summary
model.summary()
# Out:
# Model: "random_forest_model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
# =================================================================
# Total params: 1 (1.00 Byte)
# Trainable params: 0 (0.00 Byte)
# Non-trainable params: 1 (1.00 Byte)
# _________________________________________________________________
# Type: "RANDOM_FOREST"
# Task: CLASSIFICATION
# Label: "__LABEL"
#
# Input Features (16):
# 	GrayLevelNonUniformity
# 	GrayLevelNonUniformityNormalized
# 	GrayLevelVariance
# 	HighGrayLevelZoneEmphasis
# 	LargeAreaEmphasis
# 	LargeAreaHighGrayLevelEmphasis
# 	LargeAreaLowGrayLevelEmphasis
# 	LowGrayLevelZoneEmphasis
# 	SizeZoneNonUniformity
# 	SizeZoneNonUniformityNormalized
# 	SmallAreaEmphasis
# 	SmallAreaHighGrayLevelEmphasis
# 	SmallAreaLowGrayLevelEmphasis
# 	ZoneEntropy
# 	ZonePercentage
# 	ZoneVariance
#
# Trained with weights
#
# Variable Importance: INV_MEAN_MIN_DEPTH:
#     1.        "HighGrayLevelZoneEmphasis"  0.221634 ################
#     2.           "GrayLevelNonUniformity"  0.176816 #########
#     3.   "SmallAreaHighGrayLevelEmphasis"  0.166384 ########
#     4.         "LowGrayLevelZoneEmphasis"  0.166231 ########
#     5.   "LargeAreaHighGrayLevelEmphasis"  0.157952 #######
#     6.    "LargeAreaLowGrayLevelEmphasis"  0.144761 #####
#     7.    "SmallAreaLowGrayLevelEmphasis"  0.127960 ##
#     8.                      "ZoneEntropy"  0.125144 ##
#     9. "GrayLevelNonUniformityNormalized"  0.122231 ##
#    10.                "GrayLevelVariance"  0.115859 #
#    11.            "SizeZoneNonUniformity"  0.113941
#    12.                   "ZonePercentage"  0.113530
#    13.                     "ZoneVariance"  0.110407
#    14.  "SizeZoneNonUniformityNormalized"  0.107951
#    15.                "SmallAreaEmphasis"  0.107761
#    16.                "LargeAreaEmphasis"  0.107747
#
# Variable Importance: NUM_AS_ROOT:
#     1.        "HighGrayLevelZoneEmphasis" 91.000000 ################
#     2.         "LowGrayLevelZoneEmphasis" 65.000000 ###########
#     3.   "SmallAreaHighGrayLevelEmphasis" 59.000000 ##########
#     4.    "LargeAreaLowGrayLevelEmphasis" 25.000000 ####
#     5.    "SmallAreaLowGrayLevelEmphasis" 20.000000 ###
#     6.   "LargeAreaHighGrayLevelEmphasis" 17.000000 ##
#     7.                      "ZoneEntropy" 10.000000 #
#     8.           "GrayLevelNonUniformity"  6.000000
#     9. "GrayLevelNonUniformityNormalized"  5.000000
#    10.                "LargeAreaEmphasis"  1.000000
#    11.                     "ZoneVariance"  1.000000
#
# Variable Importance: NUM_NODES:
#     1.           "GrayLevelNonUniformity" 3268.000000 ################
#     2.        "HighGrayLevelZoneEmphasis" 2995.000000 #############
#     3.   "LargeAreaHighGrayLevelEmphasis" 2910.000000 ############
#     4.    "LargeAreaLowGrayLevelEmphasis" 2873.000000 ###########
#     5.   "SmallAreaHighGrayLevelEmphasis" 2742.000000 ##########
#     6.         "LowGrayLevelZoneEmphasis" 2589.000000 ########
#     7. "GrayLevelNonUniformityNormalized" 2518.000000 ########
#     8.                "GrayLevelVariance" 2491.000000 #######
#     9.                      "ZoneEntropy" 2388.000000 ######
#    10.    "SmallAreaLowGrayLevelEmphasis" 2366.000000 ######
#    11.                     "ZoneVariance" 2018.000000 ##
#    12.            "SizeZoneNonUniformity" 1940.000000 ##
#    13.  "SizeZoneNonUniformityNormalized" 1865.000000 #
#    14.                "LargeAreaEmphasis" 1823.000000
#    15.                "SmallAreaEmphasis" 1815.000000
#    16.                   "ZonePercentage" 1737.000000
#
# Variable Importance: SUM_SCORE:
#     1.        "HighGrayLevelZoneEmphasis" 307578.380292 ################
#     2.   "SmallAreaHighGrayLevelEmphasis" 207274.104685 ##########
#     3.         "LowGrayLevelZoneEmphasis" 204684.242648 ##########
#     4.           "GrayLevelNonUniformity" 134945.475559 ######
#     5.   "LargeAreaHighGrayLevelEmphasis" 104882.389986 ####
#     6.    "LargeAreaLowGrayLevelEmphasis" 95800.819720 ###
#     7.    "SmallAreaLowGrayLevelEmphasis" 92221.171059 ###
#     8.                      "ZoneEntropy" 60533.668663 #
#     9. "GrayLevelNonUniformityNormalized" 55005.043259 #
#    10.                "GrayLevelVariance" 43308.615660
#    11.            "SizeZoneNonUniformity" 35922.144238
#    12.                     "ZoneVariance" 35072.054882
#    13.                   "ZonePercentage" 32128.208408
#    14.                "LargeAreaEmphasis" 30123.640575
#    15.  "SizeZoneNonUniformityNormalized" 28849.592873
#    16.                "SmallAreaEmphasis" 28633.244455
#
#
#
# Winner takes all: true
# Out-of-bag evaluation: accuracy:0.843762 logloss:0.444256
# Number of trees: 300
# Total number of nodes: 76976
#
# Number of nodes by tree:
# Count: 300 Average: 256.587 StdDev: 14.4707
# Min: 211 Max: 309 Ignored: 0
# ----------------------------------------------
# [ 211, 215)  1   0.33%   0.33%
# [ 215, 220)  1   0.33%   0.67%
# [ 220, 225)  2   0.67%   1.33%
# [ 225, 230)  6   2.00%   3.33% #
# [ 230, 235)  5   1.67%   5.00% #
# [ 235, 240) 24   8.00%  13.00% #####
# [ 240, 245) 21   7.00%  20.00% ####
# [ 245, 250) 32  10.67%  30.67% #######
# [ 250, 255) 33  11.00%  41.67% #######
# [ 255, 260) 49  16.33%  58.00% ##########
# [ 260, 265) 36  12.00%  70.00% #######
# [ 265, 270) 40  13.33%  83.33% ########
# [ 270, 275) 17   5.67%  89.00% ###
# [ 275, 280) 20   6.67%  95.67% ####
# [ 280, 285)  5   1.67%  97.33% #
# [ 285, 290)  5   1.67%  99.00% #
# [ 290, 295)  0   0.00%  99.00%
# [ 295, 300)  2   0.67%  99.67%
# [ 300, 305)  0   0.00%  99.67%
# [ 305, 309]  1   0.33% 100.00%
#
# Depth by leafs:
# Count: 38638 Average: 9.30669 StdDev: 2.80818
# Min: 2 Max: 15 Ignored: 0
# ----------------------------------------------
# [  2,  3)   22   0.06%   0.06%
# [  3,  4)  382   0.99%   1.05% #
# [  4,  5) 1025   2.65%   3.70% ##
# [  5,  6) 2083   5.39%   9.09% ####
# [  6,  7) 3082   7.98%  17.07% ######
# [  7,  8) 4144  10.73%  27.79% ########
# [  8,  9) 4916  12.72%  40.51% ##########
# [  9, 10) 5056  13.09%  53.60% ##########
# [ 10, 11) 4795  12.41%  66.01% #########
# [ 11, 12) 4161  10.77%  76.78% ########
# [ 12, 13) 3353   8.68%  85.46% #######
# [ 13, 14) 2486   6.43%  91.89% #####
# [ 14, 15) 1715   4.44%  96.33% ###
# [ 15, 15] 1418   3.67% 100.00% ###
#
# Number of training obs by leaf:
# Count: 38638 Average: 59.1413 StdDev: 200.382
# Min: 5 Max: 3060 Ignored: 0
# ----------------------------------------------
# [    5,  157) 35844  92.77%  92.77% ##########
# [  157,  310)  1164   3.01%  95.78%
# [  310,  463)   453   1.17%  96.95%
# [  463,  616)   287   0.74%  97.70%
# [  616,  769)   180   0.47%  98.16%
# [  769,  921)   155   0.40%  98.56%
# [  921, 1074)   116   0.30%  98.86%
# [ 1074, 1227)    78   0.20%  99.07%
# [ 1227, 1380)    87   0.23%  99.29%
# [ 1380, 1533)    62   0.16%  99.45%
# [ 1533, 1685)    66   0.17%  99.62%
# [ 1685, 1838)    49   0.13%  99.75%
# [ 1838, 1991)    39   0.10%  99.85%
# [ 1991, 2144)    25   0.06%  99.91%
# [ 2144, 2297)    15   0.04%  99.95%
# [ 2297, 2449)    12   0.03%  99.98%
# [ 2449, 2602)     2   0.01%  99.99%
# [ 2602, 2755)     2   0.01%  99.99%
# [ 2755, 2908)     1   0.00% 100.00%
# [ 2908, 3060]     1   0.00% 100.00%
#
# Attribute in nodes:
# 	3268 : GrayLevelNonUniformity [NUMERICAL]
# 	2995 : HighGrayLevelZoneEmphasis [NUMERICAL]
# 	2910 : LargeAreaHighGrayLevelEmphasis [NUMERICAL]
# 	2873 : LargeAreaLowGrayLevelEmphasis [NUMERICAL]
# 	2742 : SmallAreaHighGrayLevelEmphasis [NUMERICAL]
# 	2589 : LowGrayLevelZoneEmphasis [NUMERICAL]
# 	2518 : GrayLevelNonUniformityNormalized [NUMERICAL]
# 	2491 : GrayLevelVariance [NUMERICAL]
# 	2388 : ZoneEntropy [NUMERICAL]
# 	2366 : SmallAreaLowGrayLevelEmphasis [NUMERICAL]
# 	2018 : ZoneVariance [NUMERICAL]
# 	1940 : SizeZoneNonUniformity [NUMERICAL]
# 	1865 : SizeZoneNonUniformityNormalized [NUMERICAL]
# 	1823 : LargeAreaEmphasis [NUMERICAL]
# 	1815 : SmallAreaEmphasis [NUMERICAL]
# 	1737 : ZonePercentage [NUMERICAL]
#
# Attribute in nodes with depth <= 0:
# 	91 : HighGrayLevelZoneEmphasis [NUMERICAL]
# 	65 : LowGrayLevelZoneEmphasis [NUMERICAL]
# 	59 : SmallAreaHighGrayLevelEmphasis [NUMERICAL]
# 	25 : LargeAreaLowGrayLevelEmphasis [NUMERICAL]
# 	20 : SmallAreaLowGrayLevelEmphasis [NUMERICAL]
# 	17 : LargeAreaHighGrayLevelEmphasis [NUMERICAL]
# 	10 : ZoneEntropy [NUMERICAL]
# 	6 : GrayLevelNonUniformity [NUMERICAL]
# 	5 : GrayLevelNonUniformityNormalized [NUMERICAL]
# 	1 : ZoneVariance [NUMERICAL]
# 	1 : LargeAreaEmphasis [NUMERICAL]
#
# Attribute in nodes with depth <= 1:
# 	223 : HighGrayLevelZoneEmphasis [NUMERICAL]
# 	166 : LowGrayLevelZoneEmphasis [NUMERICAL]
# 	129 : SmallAreaHighGrayLevelEmphasis [NUMERICAL]
# 	85 : LargeAreaHighGrayLevelEmphasis [NUMERICAL]
# 	76 : SmallAreaLowGrayLevelEmphasis [NUMERICAL]
# 	67 : GrayLevelNonUniformity [NUMERICAL]
# 	62 : LargeAreaLowGrayLevelEmphasis [NUMERICAL]
# 	28 : ZoneEntropy [NUMERICAL]
# 	21 : SizeZoneNonUniformity [NUMERICAL]
# 	15 : ZonePercentage [NUMERICAL]
# 	7 : GrayLevelNonUniformityNormalized [NUMERICAL]
# 	6 : SmallAreaEmphasis [NUMERICAL]
# 	5 : SizeZoneNonUniformityNormalized [NUMERICAL]
# 	5 : GrayLevelVariance [NUMERICAL]
# 	3 : ZoneVariance [NUMERICAL]
# 	2 : LargeAreaEmphasis [NUMERICAL]
#
# Attribute in nodes with depth <= 2:
# 	387 : HighGrayLevelZoneEmphasis [NUMERICAL]
# 	298 : LowGrayLevelZoneEmphasis [NUMERICAL]
# 	242 : SmallAreaHighGrayLevelEmphasis [NUMERICAL]
# 	215 : GrayLevelNonUniformity [NUMERICAL]
# 	201 : LargeAreaHighGrayLevelEmphasis [NUMERICAL]
# 	167 : LargeAreaLowGrayLevelEmphasis [NUMERICAL]
# 	149 : SmallAreaLowGrayLevelEmphasis [NUMERICAL]
# 	87 : ZoneEntropy [NUMERICAL]
# 	65 : ZonePercentage [NUMERICAL]
# 	53 : GrayLevelNonUniformityNormalized [NUMERICAL]
# 	51 : GrayLevelVariance [NUMERICAL]
# 	42 : ZoneVariance [NUMERICAL]
# 	41 : SizeZoneNonUniformity [NUMERICAL]
# 	32 : LargeAreaEmphasis [NUMERICAL]
# 	25 : SmallAreaEmphasis [NUMERICAL]
# 	23 : SizeZoneNonUniformityNormalized [NUMERICAL]
#
# Attribute in nodes with depth <= 3:
# 	610 : HighGrayLevelZoneEmphasis [NUMERICAL]
# 	445 : LowGrayLevelZoneEmphasis [NUMERICAL]
# 	439 : GrayLevelNonUniformity [NUMERICAL]
# 	381 : SmallAreaHighGrayLevelEmphasis [NUMERICAL]
# 	380 : LargeAreaHighGrayLevelEmphasis [NUMERICAL]
# 	311 : LargeAreaLowGrayLevelEmphasis [NUMERICAL]
# 	272 : SmallAreaLowGrayLevelEmphasis [NUMERICAL]
# 	219 : ZoneEntropy [NUMERICAL]
# 	177 : GrayLevelNonUniformityNormalized [NUMERICAL]
# 	165 : GrayLevelVariance [NUMERICAL]
# 	140 : ZonePercentage [NUMERICAL]
# 	123 : ZoneVariance [NUMERICAL]
# 	115 : SizeZoneNonUniformity [NUMERICAL]
# 	112 : LargeAreaEmphasis [NUMERICAL]
# 	89 : SizeZoneNonUniformityNormalized [NUMERICAL]
# 	74 : SmallAreaEmphasis [NUMERICAL]
#
# Attribute in nodes with depth <= 5:
# 	1146 : GrayLevelNonUniformity [NUMERICAL]
# 	1139 : HighGrayLevelZoneEmphasis [NUMERICAL]
# 	885 : LargeAreaHighGrayLevelEmphasis [NUMERICAL]
# 	880 : LowGrayLevelZoneEmphasis [NUMERICAL]
# 	862 : SmallAreaHighGrayLevelEmphasis [NUMERICAL]
# 	837 : LargeAreaLowGrayLevelEmphasis [NUMERICAL]
# 	668 : ZoneEntropy [NUMERICAL]
# 	635 : SmallAreaLowGrayLevelEmphasis [NUMERICAL]
# 	631 : GrayLevelNonUniformityNormalized [NUMERICAL]
# 	614 : GrayLevelVariance [NUMERICAL]
# 	442 : ZoneVariance [NUMERICAL]
# 	432 : ZonePercentage [NUMERICAL]
# 	420 : LargeAreaEmphasis [NUMERICAL]
# 	417 : SizeZoneNonUniformity [NUMERICAL]
# 	382 : SizeZoneNonUniformityNormalized [NUMERICAL]
# 	348 : SmallAreaEmphasis [NUMERICAL]
#
# Condition type in nodes:
# 	38338 : HigherCondition
# Condition type in nodes with depth <= 0:
# 	300 : HigherCondition
# Condition type in nodes with depth <= 1:
# 	900 : HigherCondition
# Condition type in nodes with depth <= 2:
# 	2078 : HigherCondition
# Condition type in nodes with depth <= 3:
# 	4052 : HigherCondition
# Condition type in nodes with depth <= 5:
# 	10738 : HigherCondition
# Node format: NOT_SET
#
# Training OOB:
# 	trees: 1, Out-of-bag evaluation: accuracy:0.808469 logloss:6.90347
# 	trees: 11, Out-of-bag evaluation: accuracy:0.831707 logloss:2.56111
# 	trees: 21, Out-of-bag evaluation: accuracy:0.84 logloss:1.82224
# 	trees: 31, Out-of-bag evaluation: accuracy:0.83743 logloss:1.43745
# 	trees: 41, Out-of-bag evaluation: accuracy:0.83676 logloss:1.09834
# 	trees: 51, Out-of-bag evaluation: accuracy:0.835739 logloss:1.02608
# 	trees: 61, Out-of-bag evaluation: accuracy:0.840102 logloss:0.917348
# 	trees: 71, Out-of-bag evaluation: accuracy:0.837041 logloss:0.883578
# 	trees: 81, Out-of-bag evaluation: accuracy:0.839961 logloss:0.845337
# 	trees: 91, Out-of-bag evaluation: accuracy:0.840842 logloss:0.80815
# 	trees: 101, Out-of-bag evaluation: accuracy:0.844113 logloss:0.77458
# 	trees: 111, Out-of-bag evaluation: accuracy:0.843903 logloss:0.771139
# 	trees: 121, Out-of-bag evaluation: accuracy:0.844853 logloss:0.738461
# 	trees: 131, Out-of-bag evaluation: accuracy:0.841792 logloss:0.671022
# 	trees: 141, Out-of-bag evaluation: accuracy:0.844853 logloss:0.605586
# 	trees: 151, Out-of-bag evaluation: accuracy:0.844783 logloss:0.57267
# 	trees: 161, Out-of-bag evaluation: accuracy:0.845803 logloss:0.572836
# 	trees: 171, Out-of-bag evaluation: accuracy:0.845593 logloss:0.574607
# 	trees: 181, Out-of-bag evaluation: accuracy:0.844643 logloss:0.575485
# 	trees: 191, Out-of-bag evaluation: accuracy:0.843762 logloss:0.576927
# 	trees: 201, Out-of-bag evaluation: accuracy:0.843482 logloss:0.544279
# 	trees: 211, Out-of-bag evaluation: accuracy:0.844572 logloss:0.544432
# 	trees: 221, Out-of-bag evaluation: accuracy:0.843552 logloss:0.544295
# 	trees: 231, Out-of-bag evaluation: accuracy:0.840561 logloss:0.545382
# 	trees: 241, Out-of-bag evaluation: accuracy:0.843622 logloss:0.546167
# 	trees: 251, Out-of-bag evaluation: accuracy:0.844783 logloss:0.513393
# 	trees: 261, Out-of-bag evaluation: accuracy:0.844783 logloss:0.512903
# 	trees: 271, Out-of-bag evaluation: accuracy:0.844923 logloss:0.479803
# 	trees: 281, Out-of-bag evaluation: accuracy:0.845733 logloss:0.446935
# 	trees: 291, Out-of-bag evaluation: accuracy:0.844713 logloss:0.445839
# 	trees: 300, Out-of-bag evaluation: accuracy:0.843762 logloss:0.444256

# %%
# Model features
model.make_inspector().features()
# Out:
# ["GrayLevelNonUniformity" (1; #0),
#  "GrayLevelNonUniformityNormalized" (1; #1),
#  "GrayLevelVariance" (1; #2),
#  "HighGrayLevelZoneEmphasis" (1; #3),
#  "LargeAreaEmphasis" (1; #4),
#  "LargeAreaHighGrayLevelEmphasis" (1; #5),
#  "LargeAreaLowGrayLevelEmphasis" (1; #6),
#  "LowGrayLevelZoneEmphasis" (1; #7),
#  "SizeZoneNonUniformity" (1; #8),
#  "SizeZoneNonUniformityNormalized" (1; #9),
#  "SmallAreaEmphasis" (1; #10),
#  "SmallAreaHighGrayLevelEmphasis" (1; #11),
#  "SmallAreaLowGrayLevelEmphasis" (1; #12),
#  "ZoneEntropy" (1; #13),
#  "ZonePercentage" (1; #14),
#  "ZoneVariance" (1; #15)]

# %%
# Feature importance
model.make_inspector().variable_importances()
# Out:
# {'INV_MEAN_MIN_DEPTH': [("HighGrayLevelZoneEmphasis" (1; #3),
#    0.22163389559123126),
#   ("GrayLevelNonUniformity" (1; #0), 0.17681637217094004),
#   ("SmallAreaHighGrayLevelEmphasis" (1; #11), 0.16638411920410898),
#   ("LowGrayLevelZoneEmphasis" (1; #7), 0.16623094887440673),
#   ("LargeAreaHighGrayLevelEmphasis" (1; #5), 0.15795153584867336),
#   ("LargeAreaLowGrayLevelEmphasis" (1; #6), 0.1447613740367575),
#   ("SmallAreaLowGrayLevelEmphasis" (1; #12), 0.12796045353981889),
#   ("ZoneEntropy" (1; #13), 0.12514427982793455),
#   ("GrayLevelNonUniformityNormalized" (1; #1), 0.12223105119397017),
#   ("GrayLevelVariance" (1; #2), 0.11585880001138196),
#   ("SizeZoneNonUniformity" (1; #8), 0.11394097552620135),
#   ("ZonePercentage" (1; #14), 0.11352958545659718),
#   ("ZoneVariance" (1; #15), 0.11040689034092642),
#   ("SizeZoneNonUniformityNormalized" (1; #9), 0.10795113982546063),
#   ("SmallAreaEmphasis" (1; #10), 0.10776117444096603),
#   ("LargeAreaEmphasis" (1; #4), 0.10774653101616026)],
#  'SUM_SCORE': [("HighGrayLevelZoneEmphasis" (1; #3), 307578.38029172365),
#   ("SmallAreaHighGrayLevelEmphasis" (1; #11), 207274.10468548755),
#   ("LowGrayLevelZoneEmphasis" (1; #7), 204684.24264810418),
#   ("GrayLevelNonUniformity" (1; #0), 134945.47555924958),
#   ("LargeAreaHighGrayLevelEmphasis" (1; #5), 104882.3899856444),
#   ("LargeAreaLowGrayLevelEmphasis" (1; #6), 95800.81971981356),
#   ("SmallAreaLowGrayLevelEmphasis" (1; #12), 92221.17105874332),
#   ("ZoneEntropy" (1; #13), 60533.66866273238),
#   ("GrayLevelNonUniformityNormalized" (1; #1), 55005.04325924162),
#   ("GrayLevelVariance" (1; #2), 43308.61565952816),
#   ("SizeZoneNonUniformity" (1; #8), 35922.14423847219),
#   ("ZoneVariance" (1; #15), 35072.054881884134),
#   ("ZonePercentage" (1; #14), 32128.20840835652),
#   ("LargeAreaEmphasis" (1; #4), 30123.640575087495),
#   ("SizeZoneNonUniformityNormalized" (1; #9), 28849.592873374757),
#   ("SmallAreaEmphasis" (1; #10), 28633.24445451723)],
#  'NUM_AS_ROOT': [("HighGrayLevelZoneEmphasis" (1; #3), 91.0),
#   ("LowGrayLevelZoneEmphasis" (1; #7), 65.0),
#   ("SmallAreaHighGrayLevelEmphasis" (1; #11), 59.0),
#   ("LargeAreaLowGrayLevelEmphasis" (1; #6), 25.0),
#   ("SmallAreaLowGrayLevelEmphasis" (1; #12), 20.0),
#   ("LargeAreaHighGrayLevelEmphasis" (1; #5), 17.0),
#   ("ZoneEntropy" (1; #13), 10.0),
#   ("GrayLevelNonUniformity" (1; #0), 6.0),
#   ("GrayLevelNonUniformityNormalized" (1; #1), 5.0),
#   ("LargeAreaEmphasis" (1; #4), 1.0),
#   ("ZoneVariance" (1; #15), 1.0)],
#  'NUM_NODES': [("GrayLevelNonUniformity" (1; #0), 3268.0),
#   ("HighGrayLevelZoneEmphasis" (1; #3), 2995.0),
#   ("LargeAreaHighGrayLevelEmphasis" (1; #5), 2910.0),
#   ("LargeAreaLowGrayLevelEmphasis" (1; #6), 2873.0),
#   ("SmallAreaHighGrayLevelEmphasis" (1; #11), 2742.0),
#   ("LowGrayLevelZoneEmphasis" (1; #7), 2589.0),
#   ("GrayLevelNonUniformityNormalized" (1; #1), 2518.0),
#   ("GrayLevelVariance" (1; #2), 2491.0),
#   ("ZoneEntropy" (1; #13), 2388.0),
#   ("SmallAreaLowGrayLevelEmphasis" (1; #12), 2366.0),
#   ("ZoneVariance" (1; #15), 2018.0),
#   ("SizeZoneNonUniformity" (1; #8), 1940.0),
#   ("SizeZoneNonUniformityNormalized" (1; #9), 1865.0),
#   ("LargeAreaEmphasis" (1; #4), 1823.0),
#   ("SmallAreaEmphasis" (1; #10), 1815.0),
#   ("ZonePercentage" (1; #14), 1737.0)]}

# %%
# Model self evaluation
model.make_inspector().evaluation()
# Out:
# Evaluation(num_examples=7617, accuracy=0.8437624390148896, loss=0.44425566784591436, rmse=None, ndcg=None, aucs=None, auuc=None, qini=None)

# %%
logs = model.make_inspector().training_logs()

plt.figure(figsize=(12, 4))
plt.subplot(1, 2, 1)
plt.plot([log.num_trees for log in logs], [log.evaluation.accuracy for log in logs])
plt.xlabel("Number of trees")
plt.ylabel("Accuracy (out-of-bag)")
plt.subplot(1, 2, 2)
plt.plot([log.num_trees for log in logs], [log.evaluation.loss for log in logs])
plt.xlabel("Number of trees")
plt.ylabel("Logloss (out-of-bag)")
plt.show()

# %% [markdown]
# Calculate the score of our hold-out validation dataset

# %%
predictions = model.predict(val_ds)
y_true      = validation_data["label"]

from sklearn.metrics import roc_auc_score
ROC_AUC = roc_auc_score(y_true, predictions)
print("The ROC AUC score is %.5f" % ROC_AUC )
# Out:
# 1/2 [==============>...............] - ETA: 0s
# 2/2 [==============================] - 0s 4ms/step
# The ROC AUC score is 0.99882

# %%
# Compute binary classification metrics with sklearn
import numpy as np
from sklearn.metrics import (
    accuracy_score,
    precision_score,
    recall_score,
    f1_score,
    roc_auc_score,
    average_precision_score,
    confusion_matrix,
    classification_report,
    matthews_corrcoef,
    log_loss,
    brier_score_loss,
)

# Get predictions (probabilities or class labels)
preds = model.predict(test_ds)
# If model outputs probabilities, convert to labels by threshold 0.5
if preds.ndim == 2:
    # For TFDF classification, preds may be class probabilities with shape (N, 2)
    if preds.shape[1] == 2:
        pos_probs = preds[:, 1]
    else:
        # If single-probability column (positive class)
        pos_probs = preds[:, -1]
    y_pred = (pos_probs >= 0.5).astype(int)
else:
    # Already class labels
    y_pred = preds.astype(int)
    pos_probs = None

# Ground truth labels (must be 0/1 integers)
y_true = test_data["label"].astype(int).to_numpy()

# Core metrics
metrics = {}
metrics["accuracy"] = accuracy_score(y_true, y_pred)
metrics["precision"] = precision_score(y_true, y_pred, zero_division=0)
metrics["recall"] = recall_score(y_true, y_pred, zero_division=0)
metrics["f1"] = f1_score(y_true, y_pred, zero_division=0)
metrics["mcc"] = matthews_corrcoef(y_true, y_pred)

# Probabilistic metrics (only if we have probabilities)
if pos_probs is not None:
    metrics["roc_auc"] = roc_auc_score(y_true, pos_probs)
    metrics["pr_auc"] = average_precision_score(y_true, pos_probs)
    metrics["log_loss"] = log_loss(y_true, pos_probs, labels=[0,1])
    metrics["brier_score"] = brier_score_loss(y_true, pos_probs)

# Confusion matrix and detailed report
cm = confusion_matrix(y_true, y_pred, labels=[0,1])
report = classification_report(y_true, y_pred, digits=4)

print("Sklearn binary metrics:")
for k, v in metrics.items():
    print(f"{k}: {v:.4f}")
print("\nConfusion matrix:\n", cm)
print("\nClassification report:\n", report)
# Out:
# 1/3 [=========>....................] - ETA: 0s
# 3/3 [==============================] - 0s 10ms/step
# Sklearn binary metrics:
# accuracy: 0.9615
# precision: 0.9112
# recall: 0.6784
# f1: 0.7778
# mcc: 0.7671
# roc_auc: 0.9666
# pr_auc: 0.8549
# log_loss: 0.1152
# brier_score: 0.0305
#
# Confusion matrix:
#  [[2041   15]
#  [  73  154]]
#
# Classification report:
#                precision    recall  f1-score   support
#
#            0     0.9655    0.9927    0.9789      2056
#            1     0.9112    0.6784    0.7778       227
#
#     accuracy                         0.9615      2283
#    macro avg     0.9384    0.8356    0.8783      2283
# weighted avg     0.9601    0.9615    0.9589      2283
