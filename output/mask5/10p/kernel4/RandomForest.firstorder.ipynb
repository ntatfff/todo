# %%
# Import packages and modules
import numpy  as np
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow_decision_forests as tfdf

from sklearn.model_selection import train_test_split
# Out:
# 2026-09-12 10:41:00.629063: I tensorflow/core/util/port.cc:113] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2026-09-12 10:41:01.001545: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2026-09-12 10:41:05.728588: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
# Check the version of TensorFlow Decision Forests
print("Found TensorFlow Decision Forests v" + tfdf.__version__)
# Out:
# Found TensorFlow Decision Forests v1.9.1

# %%
datasetPath = "dataset/10p/all/kernel3/"

# %%
# Parameters
datasetPath = "dataset/mask5/10p/firstorder/kernel4/"

# %%
# train/validation/test = 70/10/20
train_data = pd.read_csv(f"{datasetPath}dataset.train.csv")
validation_data = pd.read_csv(f"{datasetPath}dataset.validation.csv")
test_data = pd.read_csv(f"{datasetPath}dataset.test.csv")

# %%
from sklearn.utils.class_weight import compute_class_weight

# tinh class weight tren tap train
classes = np.array([0, 1])
weights = compute_class_weight(class_weight="balanced", classes=classes, y=train_data["label"])
class_weight = {0: weights[0], 1: weights[1]}

# gan sample_weight cho tung dong
train_data["sample_weight"] = train_data["label"].map(class_weight)
validation_data["sample_weight"] = validation_data["label"].map(class_weight)
test_data["sample_weight"] = test_data["label"].map(class_weight)

# Convert the dataset into a TensorFlow dataset.
train_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    train_data, label="label", weight="sample_weight"
)         
val_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    validation_data, label="label", weight="sample_weight"
)
test_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    test_data, label="label", weight="sample_weight"
)
# Out:
# 2026-09-12 10:41:18.737304: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:984] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2026-09-12 10:41:18.738370: W tensorflow/core/common_runtime/gpu/gpu_device.cc:2251] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...

# %%
import keras

# %%
# %%time

# Train a Random Forest model.
model = tfdf.keras.RandomForestModel()

# Add evaluation metrics
model.compile(
    metrics=["accuracy"]
)
model.fit(x=train_ds)

# # Train a Gradient Boosted Trees model.
# model = tfdf.keras.GradientBoostedTreesModel(num_trees=1500)
# model.fit(train_ds)
# Out:
# Use /tmp/tmpbpqmh_ev as temporary training directory
# Reading training dataset...
# Training dataset read in 0:00:02.550267. Found 7617 examples.
# Training model...
# Model trained in 0:00:00.587552
# Compiling model...
# [INFO 26-09-12 10:41:21.9278 UTC kernel.cc:1233] Loading model from path /tmp/tmpbpqmh_ev/model/ with prefix c77b51c7026f4992
# [INFO 26-09-12 10:41:22.0286 UTC decision_forest.cc:734] Model loaded with 300 root(s), 81292 node(s), and 18 input feature(s).
# [INFO 26-09-12 10:41:22.0286 UTC abstract_model.cc:1362] Engine "RandomForestOptPred" built
# [INFO 26-09-12 10:41:22.0287 UTC kernel.cc:1061] Use fast generic engine
# Model compiled.
# CPU times: user 10 s, sys: 166 ms, total: 10.2 s
# Wall time: 6.26 s

# %%
# Evaluate the model
evaluate = model.evaluate(val_ds, return_dict=True)
print()

for name, value in evaluate.items():
    print(f"{name}: {value:.4f}")
# Out:
# WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 1/2 [==============>...............] - ETA: 2s - loss: 0.0000e+00 - accuracy: 0.9920
# 2/2 [==============================] - 3s 8ms/step - loss: 0.0000e+00 - accuracy: 0.9916
# loss: 0.0000
# accuracy: 0.9916

# %%
# Model Summary
model.summary()
# Out:
# Model: "random_forest_model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
# =================================================================
# Total params: 1 (1.00 Byte)
# Trainable params: 0 (0.00 Byte)
# Non-trainable params: 1 (1.00 Byte)
# _________________________________________________________________
# Type: "RANDOM_FOREST"
# Task: CLASSIFICATION
# Label: "__LABEL"
#
# Input Features (18):
# 	10Percentile
# 	90Percentile
# 	Energy
# 	Entropy
# 	InterquartileRange
# 	Kurtosis
# 	Maximum
# 	Mean
# 	MeanAbsoluteDeviation
# 	Median
# 	Minimum
# 	Range
# 	RobustMeanAbsoluteDeviation
# 	RootMeanSquared
# 	Skewness
# 	TotalEnergy
# 	Uniformity
# 	Variance
#
# Trained with weights
#
# Variable Importance: INV_MEAN_MIN_DEPTH:
#     1.                        "Mean"  0.163922 ################
#     2.                      "Median"  0.158758 ##############
#     3.                "90Percentile"  0.154669 #############
#     4.                      "Energy"  0.142332 ##########
#     5.             "RootMeanSquared"  0.138905 #########
#     6.                     "Maximum"  0.136344 ########
#     7.                 "TotalEnergy"  0.135281 ########
#     8.                "10Percentile"  0.125127 #####
#     9.                  "Uniformity"  0.122747 ####
#    10.                    "Skewness"  0.118334 ###
#    11.                     "Entropy"  0.116114 ###
#    12.          "InterquartileRange"  0.110829 #
#    13.                    "Variance"  0.110544 #
#    14.                     "Minimum"  0.109655 #
#    15.                    "Kurtosis"  0.107429
#    16.                       "Range"  0.107221
#    17. "RobustMeanAbsoluteDeviation"  0.106320
#    18.       "MeanAbsoluteDeviation"  0.104177
#
# Variable Importance: NUM_AS_ROOT:
#     1.            "Mean" 68.000000 ################
#     2.          "Energy" 55.000000 ############
#     3.    "90Percentile" 54.000000 ############
#     4. "RootMeanSquared" 47.000000 ##########
#     5.     "TotalEnergy" 47.000000 ##########
#     6.         "Maximum" 11.000000 ##
#     7.          "Median" 11.000000 ##
#     8.    "10Percentile"  4.000000
#     9.         "Minimum"  2.000000
#    10.      "Uniformity"  1.000000
#
# Variable Importance: NUM_NODES:
#     1.                    "Skewness" 3220.000000 ################
#     2.                     "Maximum" 2953.000000 #############
#     3.                      "Median" 2849.000000 ############
#     4.                  "Uniformity" 2604.000000 #########
#     5.                "90Percentile" 2517.000000 ########
#     6.                    "Kurtosis" 2400.000000 #######
#     7.                       "Range" 2369.000000 #######
#     8.                     "Entropy" 2279.000000 ######
#     9.                     "Minimum" 2237.000000 #####
#    10.                    "Variance" 2226.000000 #####
#    11.                "10Percentile" 2044.000000 ###
#    12.                        "Mean" 1970.000000 ##
#    13.          "InterquartileRange" 1934.000000 ##
#    14. "RobustMeanAbsoluteDeviation" 1904.000000 ##
#    15.       "MeanAbsoluteDeviation" 1832.000000 #
#    16.             "RootMeanSquared" 1753.000000
#    17.                      "Energy" 1704.000000
#    18.                 "TotalEnergy" 1701.000000
#
# Variable Importance: SUM_SCORE:
#     1.                        "Mean" 197756.751025 ################
#     2.                "90Percentile" 173936.024892 #############
#     3.                      "Energy" 158239.759967 ############
#     4.                 "TotalEnergy" 141677.012489 ##########
#     5.             "RootMeanSquared" 140816.218045 ##########
#     6.                      "Median" 110139.871521 #######
#     7.                     "Maximum" 91292.170932 #####
#     8.                    "Skewness" 61888.844761 ##
#     9.                  "Uniformity" 55719.595243 ##
#    10.                "10Percentile" 55376.617274 ##
#    11.                     "Entropy" 46454.211427 #
#    12.                    "Variance" 41191.652529 #
#    13.                       "Range" 39226.870617
#    14.                     "Minimum" 38363.916705
#    15.                    "Kurtosis" 36155.354946
#    16.          "InterquartileRange" 35522.375235
#    17. "RobustMeanAbsoluteDeviation" 32649.596005
#    18.       "MeanAbsoluteDeviation" 30569.915437
#
#
#
# Winner takes all: true
# Out-of-bag evaluation: accuracy:0.826588 logloss:0.680845
# Number of trees: 300
# Total number of nodes: 81292
#
# Number of nodes by tree:
# Count: 300 Average: 270.973 StdDev: 15.9281
# Min: 223 Max: 317 Ignored: 0
# ----------------------------------------------
# [ 223, 227)  1   0.33%   0.33%
# [ 227, 232)  1   0.33%   0.67%
# [ 232, 237)  3   1.00%   1.67% #
# [ 237, 242)  6   2.00%   3.67% #
# [ 242, 246) 10   3.33%   7.00% ##
# [ 246, 251)  9   3.00%  10.00% ##
# [ 251, 256) 23   7.67%  17.67% #####
# [ 256, 261) 20   6.67%  24.33% ####
# [ 261, 265) 23   7.67%  32.00% #####
# [ 265, 270) 37  12.33%  44.33% #######
# [ 270, 275) 31  10.33%  54.67% ######
# [ 275, 280) 51  17.00%  71.67% ##########
# [ 280, 284) 25   8.33%  80.00% #####
# [ 284, 289) 22   7.33%  87.33% ####
# [ 289, 294) 17   5.67%  93.00% ###
# [ 294, 299)  9   3.00%  96.00% ##
# [ 299, 303)  2   0.67%  96.67%
# [ 303, 308)  7   2.33%  99.00% #
# [ 308, 313)  1   0.33%  99.33%
# [ 313, 317]  2   0.67% 100.00%
#
# Depth by leafs:
# Count: 40796 Average: 9.71855 StdDev: 2.87935
# Min: 2 Max: 15 Ignored: 0
# ----------------------------------------------
# [  2,  3)   97   0.24%   0.24%
# [  3,  4)  531   1.30%   1.54% #
# [  4,  5)  834   2.04%   3.58% ##
# [  5,  6) 1585   3.89%   7.47% ###
# [  6,  7) 2641   6.47%  13.94% #####
# [  7,  8) 3755   9.20%  23.15% #######
# [  8,  9) 4612  11.31%  34.45% #########
# [  9, 10) 5209  12.77%  47.22% ##########
# [ 10, 11) 5151  12.63%  59.85% ##########
# [ 11, 12) 4741  11.62%  71.47% #########
# [ 12, 13) 4085  10.01%  81.48% ########
# [ 13, 14) 3137   7.69%  89.17% ######
# [ 14, 15) 2210   5.42%  94.59% ####
# [ 15, 15] 2208   5.41% 100.00% ####
#
# Number of training obs by leaf:
# Count: 40796 Average: 56.0128 StdDev: 161.039
# Min: 5 Max: 2085 Ignored: 0
# ----------------------------------------------
# [    5,  109) 36481  89.42%  89.42% ##########
# [  109,  213)  1725   4.23%  93.65%
# [  213,  317)   815   2.00%  95.65%
# [  317,  421)   468   1.15%  96.80%
# [  421,  525)   351   0.86%  97.66%
# [  525,  629)   208   0.51%  98.17%
# [  629,  733)   144   0.35%  98.52%
# [  733,  837)   109   0.27%  98.79%
# [  837,  941)    81   0.20%  98.99%
# [  941, 1045)    89   0.22%  99.20%
# [ 1045, 1149)    87   0.21%  99.42%
# [ 1149, 1253)    46   0.11%  99.53%
# [ 1253, 1357)    41   0.10%  99.63%
# [ 1357, 1461)    97   0.24%  99.87%
# [ 1461, 1565)    31   0.08%  99.94%
# [ 1565, 1669)    14   0.03%  99.98%
# [ 1669, 1773)     2   0.00%  99.98%
# [ 1773, 1877)     3   0.01%  99.99%
# [ 1877, 1981)     2   0.00% 100.00%
# [ 1981, 2085]     2   0.00% 100.00%
#
# Attribute in nodes:
# 	3220 : Skewness [NUMERICAL]
# 	2953 : Maximum [NUMERICAL]
# 	2849 : Median [NUMERICAL]
# 	2604 : Uniformity [NUMERICAL]
# 	2517 : 90Percentile [NUMERICAL]
# 	2400 : Kurtosis [NUMERICAL]
# 	2369 : Range [NUMERICAL]
# 	2279 : Entropy [NUMERICAL]
# 	2237 : Minimum [NUMERICAL]
# 	2226 : Variance [NUMERICAL]
# 	2044 : 10Percentile [NUMERICAL]
# 	1970 : Mean [NUMERICAL]
# 	1934 : InterquartileRange [NUMERICAL]
# 	1904 : RobustMeanAbsoluteDeviation [NUMERICAL]
# 	1832 : MeanAbsoluteDeviation [NUMERICAL]
# 	1753 : RootMeanSquared [NUMERICAL]
# 	1704 : Energy [NUMERICAL]
# 	1701 : TotalEnergy [NUMERICAL]
#
# Attribute in nodes with depth <= 0:
# 	68 : Mean [NUMERICAL]
# 	55 : Energy [NUMERICAL]
# 	54 : 90Percentile [NUMERICAL]
# 	47 : TotalEnergy [NUMERICAL]
# 	47 : RootMeanSquared [NUMERICAL]
# 	11 : Median [NUMERICAL]
# 	11 : Maximum [NUMERICAL]
# 	4 : 10Percentile [NUMERICAL]
# 	2 : Minimum [NUMERICAL]
# 	1 : Uniformity [NUMERICAL]
#
# Attribute in nodes with depth <= 1:
# 	198 : Mean [NUMERICAL]
# 	146 : Median [NUMERICAL]
# 	135 : Energy [NUMERICAL]
# 	125 : TotalEnergy [NUMERICAL]
# 	116 : RootMeanSquared [NUMERICAL]
# 	77 : 90Percentile [NUMERICAL]
# 	68 : 10Percentile [NUMERICAL]
# 	19 : Maximum [NUMERICAL]
# 	12 : Minimum [NUMERICAL]
# 	2 : Uniformity [NUMERICAL]
# 	2 : Skewness [NUMERICAL]
#
# Attribute in nodes with depth <= 2:
# 	301 : Median [NUMERICAL]
# 	286 : Mean [NUMERICAL]
# 	198 : TotalEnergy [NUMERICAL]
# 	197 : Energy [NUMERICAL]
# 	177 : RootMeanSquared [NUMERICAL]
# 	167 : Skewness [NUMERICAL]
# 	132 : 90Percentile [NUMERICAL]
# 	113 : 10Percentile [NUMERICAL]
# 	76 : Maximum [NUMERICAL]
# 	73 : Uniformity [NUMERICAL]
# 	56 : Minimum [NUMERICAL]
# 	50 : Kurtosis [NUMERICAL]
# 	49 : InterquartileRange [NUMERICAL]
# 	42 : Entropy [NUMERICAL]
# 	36 : RobustMeanAbsoluteDeviation [NUMERICAL]
# 	32 : Variance [NUMERICAL]
# 	12 : Range [NUMERICAL]
# 	6 : MeanAbsoluteDeviation [NUMERICAL]
#
# Attribute in nodes with depth <= 3:
# 	405 : Median [NUMERICAL]
# 	377 : Mean [NUMERICAL]
# 	373 : Skewness [NUMERICAL]
# 	288 : 90Percentile [NUMERICAL]
# 	277 : TotalEnergy [NUMERICAL]
# 	268 : Maximum [NUMERICAL]
# 	268 : Energy [NUMERICAL]
# 	259 : RootMeanSquared [NUMERICAL]
# 	173 : Uniformity [NUMERICAL]
# 	162 : 10Percentile [NUMERICAL]
# 	149 : Kurtosis [NUMERICAL]
# 	138 : Entropy [NUMERICAL]
# 	116 : Minimum [NUMERICAL]
# 	108 : InterquartileRange [NUMERICAL]
# 	100 : Variance [NUMERICAL]
# 	93 : Range [NUMERICAL]
# 	82 : RobustMeanAbsoluteDeviation [NUMERICAL]
# 	42 : MeanAbsoluteDeviation [NUMERICAL]
#
# Attribute in nodes with depth <= 5:
# 	972 : Skewness [NUMERICAL]
# 	866 : Median [NUMERICAL]
# 	764 : Maximum [NUMERICAL]
# 	687 : 90Percentile [NUMERICAL]
# 	650 : Mean [NUMERICAL]
# 	566 : Uniformity [NUMERICAL]
# 	516 : TotalEnergy [NUMERICAL]
# 	506 : RootMeanSquared [NUMERICAL]
# 	490 : Kurtosis [NUMERICAL]
# 	490 : Energy [NUMERICAL]
# 	482 : Entropy [NUMERICAL]
# 	449 : 10Percentile [NUMERICAL]
# 	419 : Minimum [NUMERICAL]
# 	416 : Variance [NUMERICAL]
# 	408 : Range [NUMERICAL]
# 	383 : InterquartileRange [NUMERICAL]
# 	312 : RobustMeanAbsoluteDeviation [NUMERICAL]
# 	265 : MeanAbsoluteDeviation [NUMERICAL]
#
# Condition type in nodes:
# 	40496 : HigherCondition
# Condition type in nodes with depth <= 0:
# 	300 : HigherCondition
# Condition type in nodes with depth <= 1:
# 	900 : HigherCondition
# Condition type in nodes with depth <= 2:
# 	2003 : HigherCondition
# Condition type in nodes with depth <= 3:
# 	3678 : HigherCondition
# Condition type in nodes with depth <= 5:
# 	9641 : HigherCondition
# Node format: NOT_SET
#
# Training OOB:
# 	trees: 1, Out-of-bag evaluation: accuracy:0.822732 logloss:6.3894
# 	trees: 11, Out-of-bag evaluation: accuracy:0.813 logloss:5.94677
# 	trees: 21, Out-of-bag evaluation: accuracy:0.823916 logloss:2.33663
# 	trees: 32, Out-of-bag evaluation: accuracy:0.819094 logloss:1.91441
# 	trees: 42, Out-of-bag evaluation: accuracy:0.825497 logloss:1.60508
# 	trees: 52, Out-of-bag evaluation: accuracy:0.826658 logloss:1.43838
# 	trees: 62, Out-of-bag evaluation: accuracy:0.828769 logloss:1.27353
# 	trees: 72, Out-of-bag evaluation: accuracy:0.83088 logloss:1.16969
# 	trees: 82, Out-of-bag evaluation: accuracy:0.825848 logloss:1.0707
# 	trees: 92, Out-of-bag evaluation: accuracy:0.825497 logloss:1.04018
# 	trees: 102, Out-of-bag evaluation: accuracy:0.826588 logloss:1.0058
# 	trees: 112, Out-of-bag evaluation: accuracy:0.826658 logloss:0.906893
# 	trees: 122, Out-of-bag evaluation: accuracy:0.825778 logloss:0.906063
# 	trees: 132, Out-of-bag evaluation: accuracy:0.824828 logloss:0.839663
# 	trees: 143, Out-of-bag evaluation: accuracy:0.825918 logloss:0.840474
# 	trees: 153, Out-of-bag evaluation: accuracy:0.825848 logloss:0.837229
# 	trees: 163, Out-of-bag evaluation: accuracy:0.826798 logloss:0.800894
# 	trees: 173, Out-of-bag evaluation: accuracy:0.827748 logloss:0.770651
# 	trees: 183, Out-of-bag evaluation: accuracy:0.826588 logloss:0.772111
# 	trees: 193, Out-of-bag evaluation: accuracy:0.825497 logloss:0.772555
# 	trees: 203, Out-of-bag evaluation: accuracy:0.824547 logloss:0.774104
# 	trees: 213, Out-of-bag evaluation: accuracy:0.826798 logloss:0.774036
# 	trees: 223, Out-of-bag evaluation: accuracy:0.825637 logloss:0.774998
# 	trees: 233, Out-of-bag evaluation: accuracy:0.826868 logloss:0.775264
# 	trees: 243, Out-of-bag evaluation: accuracy:0.824898 logloss:0.742002
# 	trees: 253, Out-of-bag evaluation: accuracy:0.824968 logloss:0.742904
# 	trees: 263, Out-of-bag evaluation: accuracy:0.824757 logloss:0.742922
# 	trees: 273, Out-of-bag evaluation: accuracy:0.824898 logloss:0.743915
# 	trees: 283, Out-of-bag evaluation: accuracy:0.824828 logloss:0.744821
# 	trees: 293, Out-of-bag evaluation: accuracy:0.824687 logloss:0.712343
# 	trees: 300, Out-of-bag evaluation: accuracy:0.826588 logloss:0.680845

# %%
# Model features
model.make_inspector().features()
# Out:
# ["10Percentile" (1; #0),
#  "90Percentile" (1; #1),
#  "Energy" (1; #2),
#  "Entropy" (1; #3),
#  "InterquartileRange" (1; #4),
#  "Kurtosis" (1; #5),
#  "Maximum" (1; #6),
#  "Mean" (1; #7),
#  "MeanAbsoluteDeviation" (1; #8),
#  "Median" (1; #9),
#  "Minimum" (1; #10),
#  "Range" (1; #11),
#  "RobustMeanAbsoluteDeviation" (1; #12),
#  "RootMeanSquared" (1; #13),
#  "Skewness" (1; #14),
#  "TotalEnergy" (1; #15),
#  "Uniformity" (1; #16),
#  "Variance" (1; #17)]

# %%
# Feature importance
model.make_inspector().variable_importances()
# Out:
# {'INV_MEAN_MIN_DEPTH': [("Mean" (1; #7), 0.16392245222288862),
#   ("Median" (1; #9), 0.1587581471808107),
#   ("90Percentile" (1; #1), 0.15466851491503256),
#   ("Energy" (1; #2), 0.14233238203178009),
#   ("RootMeanSquared" (1; #13), 0.13890511620062632),
#   ("Maximum" (1; #6), 0.13634413073145854),
#   ("TotalEnergy" (1; #15), 0.13528123533146175),
#   ("10Percentile" (1; #0), 0.12512716465304224),
#   ("Uniformity" (1; #16), 0.12274653505691668),
#   ("Skewness" (1; #14), 0.11833392268218226),
#   ("Entropy" (1; #3), 0.11611357980655349),
#   ("InterquartileRange" (1; #4), 0.1108288300500102),
#   ("Variance" (1; #17), 0.11054435350232798),
#   ("Minimum" (1; #10), 0.10965544164636953),
#   ("Kurtosis" (1; #5), 0.10742868557676882),
#   ("Range" (1; #11), 0.10722102971769704),
#   ("RobustMeanAbsoluteDeviation" (1; #12), 0.10632013687060202),
#   ("MeanAbsoluteDeviation" (1; #8), 0.10417658049444171)],
#  'NUM_AS_ROOT': [("Mean" (1; #7), 68.0),
#   ("Energy" (1; #2), 55.0),
#   ("90Percentile" (1; #1), 54.0),
#   ("RootMeanSquared" (1; #13), 47.0),
#   ("TotalEnergy" (1; #15), 47.0),
#   ("Maximum" (1; #6), 11.0),
#   ("Median" (1; #9), 11.0),
#   ("10Percentile" (1; #0), 4.0),
#   ("Minimum" (1; #10), 2.0),
#   ("Uniformity" (1; #16), 1.0)],
#  'SUM_SCORE': [("Mean" (1; #7), 197756.75102494293),
#   ("90Percentile" (1; #1), 173936.02489213482),
#   ("Energy" (1; #2), 158239.75996652138),
#   ("TotalEnergy" (1; #15), 141677.01248923512),
#   ("RootMeanSquared" (1; #13), 140816.2180447782),
#   ("Median" (1; #9), 110139.87152064987),
#   ("Maximum" (1; #6), 91292.17093245103),
#   ("Skewness" (1; #14), 61888.84476127064),
#   ("Uniformity" (1; #16), 55719.5952433676),
#   ("10Percentile" (1; #0), 55376.61727352502),
#   ("Entropy" (1; #3), 46454.21142665258),
#   ("Variance" (1; #17), 41191.65252946309),
#   ("Range" (1; #11), 39226.870616713764),
#   ("Minimum" (1; #10), 38363.91670479988),
#   ("Kurtosis" (1; #5), 36155.35494579914),
#   ("InterquartileRange" (1; #4), 35522.375235209875),
#   ("RobustMeanAbsoluteDeviation" (1; #12), 32649.59600472257),
#   ("MeanAbsoluteDeviation" (1; #8), 30569.915437242846)],
#  'NUM_NODES': [("Skewness" (1; #14), 3220.0),
#   ("Maximum" (1; #6), 2953.0),
#   ("Median" (1; #9), 2849.0),
#   ("Uniformity" (1; #16), 2604.0),
#   ("90Percentile" (1; #1), 2517.0),
#   ("Kurtosis" (1; #5), 2400.0),
#   ("Range" (1; #11), 2369.0),
#   ("Entropy" (1; #3), 2279.0),
#   ("Minimum" (1; #10), 2237.0),
#   ("Variance" (1; #17), 2226.0),
#   ("10Percentile" (1; #0), 2044.0),
#   ("Mean" (1; #7), 1970.0),
#   ("InterquartileRange" (1; #4), 1934.0),
#   ("RobustMeanAbsoluteDeviation" (1; #12), 1904.0),
#   ("MeanAbsoluteDeviation" (1; #8), 1832.0),
#   ("RootMeanSquared" (1; #13), 1753.0),
#   ("Energy" (1; #2), 1704.0),
#   ("TotalEnergy" (1; #15), 1701.0)]}

# %%
# Model self evaluation
model.make_inspector().evaluation()
# Out:
# Evaluation(num_examples=7617, accuracy=0.8265877398502344, loss=0.6808447196394825, rmse=None, ndcg=None, aucs=None, auuc=None, qini=None)

# %%
logs = model.make_inspector().training_logs()

plt.figure(figsize=(12, 4))
plt.subplot(1, 2, 1)
plt.plot([log.num_trees for log in logs], [log.evaluation.accuracy for log in logs])
plt.xlabel("Number of trees")
plt.ylabel("Accuracy (out-of-bag)")
plt.subplot(1, 2, 2)
plt.plot([log.num_trees for log in logs], [log.evaluation.loss for log in logs])
plt.xlabel("Number of trees")
plt.ylabel("Logloss (out-of-bag)")
plt.show()

# %% [markdown]
# Calculate the score of our hold-out validation dataset

# %%
predictions = model.predict(val_ds)
y_true      = validation_data["label"]

from sklearn.metrics import roc_auc_score
ROC_AUC = roc_auc_score(y_true, predictions)
print("The ROC AUC score is %.5f" % ROC_AUC )
# Out:
# 1/2 [==============>...............] - ETA: 0s
# 2/2 [==============================] - 0s 4ms/step
# The ROC AUC score is 0.99610

# %%
# Compute binary classification metrics with sklearn
import numpy as np
from sklearn.metrics import (
    accuracy_score,
    precision_score,
    recall_score,
    f1_score,
    roc_auc_score,
    average_precision_score,
    confusion_matrix,
    classification_report,
    matthews_corrcoef,
    log_loss,
    brier_score_loss,
)

# Get predictions (probabilities or class labels)
preds = model.predict(test_ds)
# If model outputs probabilities, convert to labels by threshold 0.5
if preds.ndim == 2:
    # For TFDF classification, preds may be class probabilities with shape (N, 2)
    if preds.shape[1] == 2:
        pos_probs = preds[:, 1]
    else:
        # If single-probability column (positive class)
        pos_probs = preds[:, -1]
    y_pred = (pos_probs >= 0.5).astype(int)
else:
    # Already class labels
    y_pred = preds.astype(int)
    pos_probs = None

# Ground truth labels (must be 0/1 integers)
y_true = test_data["label"].astype(int).to_numpy()

# Core metrics
metrics = {}
metrics["accuracy"] = accuracy_score(y_true, y_pred)
metrics["precision"] = precision_score(y_true, y_pred, zero_division=0)
metrics["recall"] = recall_score(y_true, y_pred, zero_division=0)
metrics["f1"] = f1_score(y_true, y_pred, zero_division=0)
metrics["mcc"] = matthews_corrcoef(y_true, y_pred)

# Probabilistic metrics (only if we have probabilities)
if pos_probs is not None:
    metrics["roc_auc"] = roc_auc_score(y_true, pos_probs)
    metrics["pr_auc"] = average_precision_score(y_true, pos_probs)
    metrics["log_loss"] = log_loss(y_true, pos_probs, labels=[0,1])
    metrics["brier_score"] = brier_score_loss(y_true, pos_probs)

# Confusion matrix and detailed report
cm = confusion_matrix(y_true, y_pred, labels=[0,1])
report = classification_report(y_true, y_pred, digits=4)

print("Sklearn binary metrics:")
for k, v in metrics.items():
    print(f"{k}: {v:.4f}")
print("\nConfusion matrix:\n", cm)
print("\nClassification report:\n", report)
# Out:
# 1/3 [=========>....................] - ETA: 0s
# 3/3 [==============================] - 0s 10ms/step
# Sklearn binary metrics:
# accuracy: 0.9654
# precision: 0.8700
# recall: 0.7665
# f1: 0.8150
# mcc: 0.7979
# roc_auc: 0.9588
# pr_auc: 0.8681
# log_loss: 0.1289
# brier_score: 0.0273
#
# Confusion matrix:
#  [[2030   26]
#  [  53  174]]
#
# Classification report:
#                precision    recall  f1-score   support
#
#            0     0.9746    0.9874    0.9809      2056
#            1     0.8700    0.7665    0.8150       227
#
#     accuracy                         0.9654      2283
#    macro avg     0.9223    0.8769    0.8980      2283
# weighted avg     0.9642    0.9654    0.9644      2283
