# %%
# Import packages and modules
import numpy  as np
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow_decision_forests as tfdf

from sklearn.model_selection import train_test_split
# Out:
# 2026-09-12 10:42:10.125170: I tensorflow/core/util/port.cc:113] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2026-09-12 10:42:10.479265: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2026-09-12 10:42:15.852773: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
# Check the version of TensorFlow Decision Forests
print("Found TensorFlow Decision Forests v" + tfdf.__version__)
# Out:
# Found TensorFlow Decision Forests v1.9.1

# %%
datasetPath = "dataset/10p/all/kernel3/"

# %%
# Parameters
datasetPath = "dataset/mask5/10p/gldm/kernel4/"

# %%
# train/validation/test = 70/10/20
train_data = pd.read_csv(f"{datasetPath}dataset.train.csv")
validation_data = pd.read_csv(f"{datasetPath}dataset.validation.csv")
test_data = pd.read_csv(f"{datasetPath}dataset.test.csv")

# %%
from sklearn.utils.class_weight import compute_class_weight

# tinh class weight tren tap train
classes = np.array([0, 1])
weights = compute_class_weight(class_weight="balanced", classes=classes, y=train_data["label"])
class_weight = {0: weights[0], 1: weights[1]}

# gan sample_weight cho tung dong
train_data["sample_weight"] = train_data["label"].map(class_weight)
validation_data["sample_weight"] = validation_data["label"].map(class_weight)
test_data["sample_weight"] = test_data["label"].map(class_weight)

# Convert the dataset into a TensorFlow dataset.
train_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    train_data, label="label", weight="sample_weight"
)         
val_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    validation_data, label="label", weight="sample_weight"
)
test_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    test_data, label="label", weight="sample_weight"
)
# Out:
# 2026-09-12 10:42:28.240082: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:984] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2026-09-12 10:42:28.241603: W tensorflow/core/common_runtime/gpu/gpu_device.cc:2251] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...

# %%
import keras

# %%
# %%time

# Train a Random Forest model.
model = tfdf.keras.RandomForestModel()

# Add evaluation metrics
model.compile(
    metrics=["accuracy"]
)
model.fit(x=train_ds)

# # Train a Gradient Boosted Trees model.
# model = tfdf.keras.GradientBoostedTreesModel(num_trees=1500)
# model.fit(train_ds)
# Out:
# Use /tmp/tmp2xku5ecj as temporary training directory
# Reading training dataset...
# Training dataset read in 0:00:02.543659. Found 7617 examples.
# Training model...
# Model trained in 0:00:00.516959
# Compiling model...
# [INFO 26-09-12 10:42:31.3545 UTC kernel.cc:1233] Loading model from path /tmp/tmp2xku5ecj/model/ with prefix 2e5a57fb51174c8f
# [INFO 26-09-12 10:42:31.4480 UTC decision_forest.cc:734] Model loaded with 300 root(s), 73432 node(s), and 14 input feature(s).
# [INFO 26-09-12 10:42:31.4480 UTC abstract_model.cc:1362] Engine "RandomForestOptPred" built
# [INFO 26-09-12 10:42:31.4481 UTC kernel.cc:1061] Use fast generic engine
# Model compiled.
# CPU times: user 9.29 s, sys: 191 ms, total: 9.48 s
# Wall time: 6.21 s

# %%
# Evaluate the model
evaluate = model.evaluate(val_ds, return_dict=True)
print()

for name, value in evaluate.items():
    print(f"{name}: {value:.4f}")
# Out:
# WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 1/2 [==============>...............] - ETA: 3s - loss: 0.0000e+00 - accuracy: 0.9920
# 2/2 [==============================] - 3s 9ms/step - loss: 0.0000e+00 - accuracy: 0.9898
# loss: 0.0000
# accuracy: 0.9898

# %%
# Model Summary
model.summary()
# Out:
# Model: "random_forest_model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
# =================================================================
# Total params: 1 (1.00 Byte)
# Trainable params: 0 (0.00 Byte)
# Non-trainable params: 1 (1.00 Byte)
# _________________________________________________________________
# Type: "RANDOM_FOREST"
# Task: CLASSIFICATION
# Label: "__LABEL"
#
# Input Features (14):
# 	DependenceEntropy
# 	DependenceNonUniformity
# 	DependenceNonUniformityNormalized
# 	DependenceVariance
# 	GrayLevelNonUniformity
# 	GrayLevelVariance
# 	HighGrayLevelEmphasis
# 	LargeDependenceEmphasis
# 	LargeDependenceHighGrayLevelEmphasis
# 	LargeDependenceLowGrayLevelEmphasis
# 	LowGrayLevelEmphasis
# 	SmallDependenceEmphasis
# 	SmallDependenceHighGrayLevelEmphasis
# 	SmallDependenceLowGrayLevelEmphasis
#
# Trained with weights
#
# Variable Importance: INV_MEAN_MIN_DEPTH:
#     1.                "HighGrayLevelEmphasis"  0.248336 ################
#     2. "LargeDependenceHighGrayLevelEmphasis"  0.239649 ##############
#     3.                 "LowGrayLevelEmphasis"  0.177862 #######
#     4.                    "DependenceEntropy"  0.161554 #####
#     5. "SmallDependenceHighGrayLevelEmphasis"  0.157331 #####
#     6.  "SmallDependenceLowGrayLevelEmphasis"  0.136837 ##
#     7.  "LargeDependenceLowGrayLevelEmphasis"  0.129460 #
#     8.               "GrayLevelNonUniformity"  0.127243 #
#     9.                    "GrayLevelVariance"  0.121986 #
#    10.                   "DependenceVariance"  0.116958
#    11.              "SmallDependenceEmphasis"  0.116741
#    12.    "DependenceNonUniformityNormalized"  0.114417
#    13.              "DependenceNonUniformity"  0.114054
#    14.              "LargeDependenceEmphasis"  0.113314
#
# Variable Importance: NUM_AS_ROOT:
#     1.                "HighGrayLevelEmphasis" 108.000000 ################
#     2.                 "LowGrayLevelEmphasis" 80.000000 ###########
#     3. "LargeDependenceHighGrayLevelEmphasis" 41.000000 #####
#     4. "SmallDependenceHighGrayLevelEmphasis" 41.000000 #####
#     5.  "LargeDependenceLowGrayLevelEmphasis" 13.000000 #
#     6.  "SmallDependenceLowGrayLevelEmphasis" 10.000000 #
#     7.               "GrayLevelNonUniformity"  4.000000
#     8.                    "DependenceEntropy"  3.000000
#
# Variable Importance: NUM_NODES:
#     1. "LargeDependenceHighGrayLevelEmphasis" 3695.000000 ################
#     2.                    "DependenceEntropy" 3625.000000 ###############
#     3.                "HighGrayLevelEmphasis" 3286.000000 ############
#     4.               "GrayLevelNonUniformity" 2927.000000 #########
#     5. "SmallDependenceHighGrayLevelEmphasis" 2906.000000 #########
#     6.  "SmallDependenceLowGrayLevelEmphasis" 2733.000000 ########
#     7.                    "GrayLevelVariance" 2720.000000 ########
#     8.                 "LowGrayLevelEmphasis" 2508.000000 ######
#     9.  "LargeDependenceLowGrayLevelEmphasis" 2489.000000 ######
#    10.              "SmallDependenceEmphasis" 2288.000000 ####
#    11.                   "DependenceVariance" 2266.000000 ####
#    12.    "DependenceNonUniformityNormalized" 1743.000000
#    13.              "LargeDependenceEmphasis" 1710.000000
#    14.              "DependenceNonUniformity" 1670.000000
#
# Variable Importance: SUM_SCORE:
#     1.                "HighGrayLevelEmphasis" 350805.124468 ################
#     2. "LargeDependenceHighGrayLevelEmphasis" 254302.304530 ###########
#     3.                 "LowGrayLevelEmphasis" 209849.548690 #########
#     4. "SmallDependenceHighGrayLevelEmphasis" 152186.154215 ######
#     5.                    "DependenceEntropy" 117464.721052 ####
#     6.  "SmallDependenceLowGrayLevelEmphasis" 77078.729831 ##
#     7.  "LargeDependenceLowGrayLevelEmphasis" 71317.200319 ##
#     8.               "GrayLevelNonUniformity" 59042.692090 #
#     9.                    "GrayLevelVariance" 48510.000154 #
#    10.              "SmallDependenceEmphasis" 38649.605038
#    11.                   "DependenceVariance" 38643.667815
#    12.    "DependenceNonUniformityNormalized" 30194.213574
#    13.              "DependenceNonUniformity" 29292.889444
#    14.              "LargeDependenceEmphasis" 28028.364473
#
#
#
# Winner takes all: true
# Out-of-bag evaluation: accuracy:0.85794 logloss:0.597385
# Number of trees: 300
# Total number of nodes: 73432
#
# Number of nodes by tree:
# Count: 300 Average: 244.773 StdDev: 14.2165
# Min: 201 Max: 279 Ignored: 0
# ----------------------------------------------
# [ 201, 204)  1   0.33%   0.33%
# [ 204, 208)  1   0.33%   0.67%
# [ 208, 212)  0   0.00%   0.67%
# [ 212, 216)  4   1.33%   2.00% #
# [ 216, 220)  6   2.00%   4.00% ##
# [ 220, 224) 10   3.33%   7.33% ###
# [ 224, 228) 15   5.00%  12.33% ####
# [ 228, 232) 19   6.33%  18.67% #####
# [ 232, 236) 22   7.33%  26.00% ######
# [ 236, 240) 30  10.00%  36.00% #########
# [ 240, 244) 35  11.67%  47.67% ##########
# [ 244, 248) 34  11.33%  59.00% ##########
# [ 248, 252) 32  10.67%  69.67% #########
# [ 252, 256) 27   9.00%  78.67% ########
# [ 256, 260) 19   6.33%  85.00% #####
# [ 260, 264) 20   6.67%  91.67% ######
# [ 264, 268)  8   2.67%  94.33% ##
# [ 268, 272)  7   2.33%  96.67% ##
# [ 272, 276)  6   2.00%  98.67% ##
# [ 276, 279]  4   1.33% 100.00% #
#
# Depth by leafs:
# Count: 36866 Average: 8.95844 StdDev: 2.64326
# Min: 2 Max: 15 Ignored: 0
# ----------------------------------------------
# [  2,  3)    9   0.02%   0.02%
# [  3,  4)  336   0.91%   0.94% #
# [  4,  5)  987   2.68%   3.61% ##
# [  5,  6) 2120   5.75%   9.36% ####
# [  6,  7) 3541   9.61%  18.97% #######
# [  7,  8) 4496  12.20%  31.16% #########
# [  8,  9) 5080  13.78%  44.94% ##########
# [  9, 10) 5124  13.90%  58.84% ##########
# [ 10, 11) 4719  12.80%  71.64% #########
# [ 11, 12) 3869  10.49%  82.14% ########
# [ 12, 13) 2844   7.71%  89.85% ######
# [ 13, 14) 1833   4.97%  94.82% ####
# [ 14, 15) 1112   3.02%  97.84% ##
# [ 15, 15]  796   2.16% 100.00% ##
#
# Number of training obs by leaf:
# Count: 36866 Average: 61.9839 StdDev: 229.798
# Min: 5 Max: 3614 Ignored: 0
# ----------------------------------------------
# [    5,  185) 34708  94.15%  94.15% ##########
# [  185,  366)   786   2.13%  96.28%
# [  366,  546)   345   0.94%  97.21%
# [  546,  727)   231   0.63%  97.84%
# [  727,  907)   150   0.41%  98.25%
# [  907, 1088)   145   0.39%  98.64%
# [ 1088, 1268)    76   0.21%  98.85%
# [ 1268, 1449)    94   0.25%  99.10%
# [ 1449, 1629)    89   0.24%  99.34%
# [ 1629, 1810)    65   0.18%  99.52%
# [ 1810, 1990)    63   0.17%  99.69%
# [ 1990, 2171)    45   0.12%  99.81%
# [ 2171, 2351)    21   0.06%  99.87%
# [ 2351, 2532)    15   0.04%  99.91%
# [ 2532, 2712)     8   0.02%  99.93%
# [ 2712, 2893)     9   0.02%  99.96%
# [ 2893, 3073)     7   0.02%  99.98%
# [ 3073, 3254)     3   0.01%  99.98%
# [ 3254, 3434)     3   0.01%  99.99%
# [ 3434, 3614]     3   0.01% 100.00%
#
# Attribute in nodes:
# 	3695 : LargeDependenceHighGrayLevelEmphasis [NUMERICAL]
# 	3625 : DependenceEntropy [NUMERICAL]
# 	3286 : HighGrayLevelEmphasis [NUMERICAL]
# 	2927 : GrayLevelNonUniformity [NUMERICAL]
# 	2906 : SmallDependenceHighGrayLevelEmphasis [NUMERICAL]
# 	2733 : SmallDependenceLowGrayLevelEmphasis [NUMERICAL]
# 	2720 : GrayLevelVariance [NUMERICAL]
# 	2508 : LowGrayLevelEmphasis [NUMERICAL]
# 	2489 : LargeDependenceLowGrayLevelEmphasis [NUMERICAL]
# 	2288 : SmallDependenceEmphasis [NUMERICAL]
# 	2266 : DependenceVariance [NUMERICAL]
# 	1743 : DependenceNonUniformityNormalized [NUMERICAL]
# 	1710 : LargeDependenceEmphasis [NUMERICAL]
# 	1670 : DependenceNonUniformity [NUMERICAL]
#
# Attribute in nodes with depth <= 0:
# 	108 : HighGrayLevelEmphasis [NUMERICAL]
# 	80 : LowGrayLevelEmphasis [NUMERICAL]
# 	41 : SmallDependenceHighGrayLevelEmphasis [NUMERICAL]
# 	41 : LargeDependenceHighGrayLevelEmphasis [NUMERICAL]
# 	13 : LargeDependenceLowGrayLevelEmphasis [NUMERICAL]
# 	10 : SmallDependenceLowGrayLevelEmphasis [NUMERICAL]
# 	4 : GrayLevelNonUniformity [NUMERICAL]
# 	3 : DependenceEntropy [NUMERICAL]
#
# Attribute in nodes with depth <= 1:
# 	274 : HighGrayLevelEmphasis [NUMERICAL]
# 	182 : LowGrayLevelEmphasis [NUMERICAL]
# 	168 : LargeDependenceHighGrayLevelEmphasis [NUMERICAL]
# 	101 : SmallDependenceHighGrayLevelEmphasis [NUMERICAL]
# 	67 : SmallDependenceLowGrayLevelEmphasis [NUMERICAL]
# 	44 : LargeDependenceLowGrayLevelEmphasis [NUMERICAL]
# 	25 : DependenceEntropy [NUMERICAL]
# 	14 : GrayLevelNonUniformity [NUMERICAL]
# 	8 : DependenceNonUniformityNormalized [NUMERICAL]
# 	7 : SmallDependenceEmphasis [NUMERICAL]
# 	4 : DependenceNonUniformity [NUMERICAL]
# 	3 : GrayLevelVariance [NUMERICAL]
# 	2 : LargeDependenceEmphasis [NUMERICAL]
# 	1 : DependenceVariance [NUMERICAL]
#
# Attribute in nodes with depth <= 2:
# 	487 : HighGrayLevelEmphasis [NUMERICAL]
# 	391 : LargeDependenceHighGrayLevelEmphasis [NUMERICAL]
# 	288 : LowGrayLevelEmphasis [NUMERICAL]
# 	191 : SmallDependenceHighGrayLevelEmphasis [NUMERICAL]
# 	183 : DependenceEntropy [NUMERICAL]
# 	147 : SmallDependenceLowGrayLevelEmphasis [NUMERICAL]
# 	100 : LargeDependenceLowGrayLevelEmphasis [NUMERICAL]
# 	86 : GrayLevelNonUniformity [NUMERICAL]
# 	45 : GrayLevelVariance [NUMERICAL]
# 	40 : DependenceNonUniformityNormalized [NUMERICAL]
# 	36 : SmallDependenceEmphasis [NUMERICAL]
# 	36 : DependenceNonUniformity [NUMERICAL]
# 	33 : DependenceVariance [NUMERICAL]
# 	28 : LargeDependenceEmphasis [NUMERICAL]
#
# Attribute in nodes with depth <= 3:
# 	730 : HighGrayLevelEmphasis [NUMERICAL]
# 	687 : LargeDependenceHighGrayLevelEmphasis [NUMERICAL]
# 	451 : DependenceEntropy [NUMERICAL]
# 	438 : LowGrayLevelEmphasis [NUMERICAL]
# 	322 : SmallDependenceHighGrayLevelEmphasis [NUMERICAL]
# 	275 : GrayLevelNonUniformity [NUMERICAL]
# 	265 : SmallDependenceLowGrayLevelEmphasis [NUMERICAL]
# 	220 : LargeDependenceLowGrayLevelEmphasis [NUMERICAL]
# 	183 : GrayLevelVariance [NUMERICAL]
# 	130 : SmallDependenceEmphasis [NUMERICAL]
# 	129 : DependenceVariance [NUMERICAL]
# 	113 : LargeDependenceEmphasis [NUMERICAL]
# 	97 : DependenceNonUniformityNormalized [NUMERICAL]
# 	97 : DependenceNonUniformity [NUMERICAL]
#
# Attribute in nodes with depth <= 5:
# 	1416 : HighGrayLevelEmphasis [NUMERICAL]
# 	1404 : LargeDependenceHighGrayLevelEmphasis [NUMERICAL]
# 	1251 : DependenceEntropy [NUMERICAL]
# 	928 : SmallDependenceHighGrayLevelEmphasis [NUMERICAL]
# 	912 : GrayLevelNonUniformity [NUMERICAL]
# 	891 : LowGrayLevelEmphasis [NUMERICAL]
# 	741 : SmallDependenceLowGrayLevelEmphasis [NUMERICAL]
# 	726 : GrayLevelVariance [NUMERICAL]
# 	652 : LargeDependenceLowGrayLevelEmphasis [NUMERICAL]
# 	559 : SmallDependenceEmphasis [NUMERICAL]
# 	541 : DependenceVariance [NUMERICAL]
# 	443 : DependenceNonUniformity [NUMERICAL]
# 	436 : DependenceNonUniformityNormalized [NUMERICAL]
# 	432 : LargeDependenceEmphasis [NUMERICAL]
#
# Condition type in nodes:
# 	36566 : HigherCondition
# Condition type in nodes with depth <= 0:
# 	300 : HigherCondition
# Condition type in nodes with depth <= 1:
# 	900 : HigherCondition
# Condition type in nodes with depth <= 2:
# 	2091 : HigherCondition
# Condition type in nodes with depth <= 3:
# 	4137 : HigherCondition
# Condition type in nodes with depth <= 5:
# 	11332 : HigherCondition
# Node format: NOT_SET
#
# Training OOB:
# 	trees: 1, Out-of-bag evaluation: accuracy:0.84945 logloss:5.42638
# 	trees: 12, Out-of-bag evaluation: accuracy:0.833112 logloss:5.47831
# 	trees: 22, Out-of-bag evaluation: accuracy:0.844783 logloss:1.71475
# 	trees: 32, Out-of-bag evaluation: accuracy:0.850446 logloss:1.38724
# 	trees: 45, Out-of-bag evaluation: accuracy:0.852908 logloss:1.11228
# 	trees: 55, Out-of-bag evaluation: accuracy:0.855229 logloss:1.00918
# 	trees: 65, Out-of-bag evaluation: accuracy:0.855159 logloss:1.00792
# 	trees: 75, Out-of-bag evaluation: accuracy:0.856639 logloss:0.973807
# 	trees: 85, Out-of-bag evaluation: accuracy:0.860121 logloss:0.937104
# 	trees: 95, Out-of-bag evaluation: accuracy:0.860121 logloss:0.899079
# 	trees: 105, Out-of-bag evaluation: accuracy:0.861071 logloss:0.896111
# 	trees: 115, Out-of-bag evaluation: accuracy:0.860261 logloss:0.862587
# 	trees: 125, Out-of-bag evaluation: accuracy:0.861071 logloss:0.828414
# 	trees: 135, Out-of-bag evaluation: accuracy:0.85896 logloss:0.82779
# 	trees: 145, Out-of-bag evaluation: accuracy:0.85801 logloss:0.730207
# 	trees: 155, Out-of-bag evaluation: accuracy:0.856779 logloss:0.662773
# 	trees: 165, Out-of-bag evaluation: accuracy:0.859981 logloss:0.630883
# 	trees: 175, Out-of-bag evaluation: accuracy:0.85896 logloss:0.630089
# 	trees: 185, Out-of-bag evaluation: accuracy:0.85713 logloss:0.632348
# 	trees: 195, Out-of-bag evaluation: accuracy:0.858291 logloss:0.629451
# 	trees: 205, Out-of-bag evaluation: accuracy:0.859241 logloss:0.628432
# 	trees: 215, Out-of-bag evaluation: accuracy:0.8572 logloss:0.629676
# 	trees: 225, Out-of-bag evaluation: accuracy:0.85734 logloss:0.629408
# 	trees: 235, Out-of-bag evaluation: accuracy:0.858291 logloss:0.628584
# 	trees: 245, Out-of-bag evaluation: accuracy:0.85822 logloss:0.62901
# 	trees: 255, Out-of-bag evaluation: accuracy:0.85815 logloss:0.629029
# 	trees: 265, Out-of-bag evaluation: accuracy:0.856109 logloss:0.629096
# 	trees: 275, Out-of-bag evaluation: accuracy:0.85713 logloss:0.629274
# 	trees: 285, Out-of-bag evaluation: accuracy:0.85706 logloss:0.59844
# 	trees: 295, Out-of-bag evaluation: accuracy:0.85801 logloss:0.597562
# 	trees: 300, Out-of-bag evaluation: accuracy:0.85794 logloss:0.597385

# %%
# Model features
model.make_inspector().features()
# Out:
# ["DependenceEntropy" (1; #0),
#  "DependenceNonUniformity" (1; #1),
#  "DependenceNonUniformityNormalized" (1; #2),
#  "DependenceVariance" (1; #3),
#  "GrayLevelNonUniformity" (1; #4),
#  "GrayLevelVariance" (1; #5),
#  "HighGrayLevelEmphasis" (1; #6),
#  "LargeDependenceEmphasis" (1; #7),
#  "LargeDependenceHighGrayLevelEmphasis" (1; #8),
#  "LargeDependenceLowGrayLevelEmphasis" (1; #9),
#  "LowGrayLevelEmphasis" (1; #10),
#  "SmallDependenceEmphasis" (1; #11),
#  "SmallDependenceHighGrayLevelEmphasis" (1; #12),
#  "SmallDependenceLowGrayLevelEmphasis" (1; #13)]

# %%
# Feature importance
model.make_inspector().variable_importances()
# Out:
# {'INV_MEAN_MIN_DEPTH': [("HighGrayLevelEmphasis" (1; #6), 0.24833586596167714),
#   ("LargeDependenceHighGrayLevelEmphasis" (1; #8), 0.23964866805932325),
#   ("LowGrayLevelEmphasis" (1; #10), 0.17786238645455443),
#   ("DependenceEntropy" (1; #0), 0.16155357119996805),
#   ("SmallDependenceHighGrayLevelEmphasis" (1; #12), 0.15733059270929975),
#   ("SmallDependenceLowGrayLevelEmphasis" (1; #13), 0.13683668134689944),
#   ("LargeDependenceLowGrayLevelEmphasis" (1; #9), 0.12946030350118995),
#   ("GrayLevelNonUniformity" (1; #4), 0.12724270057976728),
#   ("GrayLevelVariance" (1; #5), 0.12198609432030802),
#   ("DependenceVariance" (1; #3), 0.11695815743234193),
#   ("SmallDependenceEmphasis" (1; #11), 0.11674140641093078),
#   ("DependenceNonUniformityNormalized" (1; #2), 0.11441656658258789),
#   ("DependenceNonUniformity" (1; #1), 0.11405413499188931),
#   ("LargeDependenceEmphasis" (1; #7), 0.11331427190738752)],
#  'NUM_AS_ROOT': [("HighGrayLevelEmphasis" (1; #6), 108.0),
#   ("LowGrayLevelEmphasis" (1; #10), 80.0),
#   ("LargeDependenceHighGrayLevelEmphasis" (1; #8), 41.0),
#   ("SmallDependenceHighGrayLevelEmphasis" (1; #12), 41.0),
#   ("LargeDependenceLowGrayLevelEmphasis" (1; #9), 13.0),
#   ("SmallDependenceLowGrayLevelEmphasis" (1; #13), 10.0),
#   ("GrayLevelNonUniformity" (1; #4), 4.0),
#   ("DependenceEntropy" (1; #0), 3.0)],
#  'SUM_SCORE': [("HighGrayLevelEmphasis" (1; #6), 350805.1244676595),
#   ("LargeDependenceHighGrayLevelEmphasis" (1; #8), 254302.30452961847),
#   ("LowGrayLevelEmphasis" (1; #10), 209849.54869012858),
#   ("SmallDependenceHighGrayLevelEmphasis" (1; #12), 152186.15421512828),
#   ("DependenceEntropy" (1; #0), 117464.72105195408),
#   ("SmallDependenceLowGrayLevelEmphasis" (1; #13), 77078.72983132268),
#   ("LargeDependenceLowGrayLevelEmphasis" (1; #9), 71317.20031936382),
#   ("GrayLevelNonUniformity" (1; #4), 59042.69208977982),
#   ("GrayLevelVariance" (1; #5), 48510.00015409789),
#   ("SmallDependenceEmphasis" (1; #11), 38649.60503786461),
#   ("DependenceVariance" (1; #3), 38643.66781533407),
#   ("DependenceNonUniformityNormalized" (1; #2), 30194.213574329722),
#   ("DependenceNonUniformity" (1; #1), 29292.889443831235),
#   ("LargeDependenceEmphasis" (1; #7), 28028.364473118407)],
#  'NUM_NODES': [("LargeDependenceHighGrayLevelEmphasis" (1; #8), 3695.0),
#   ("DependenceEntropy" (1; #0), 3625.0),
#   ("HighGrayLevelEmphasis" (1; #6), 3286.0),
#   ("GrayLevelNonUniformity" (1; #4), 2927.0),
#   ("SmallDependenceHighGrayLevelEmphasis" (1; #12), 2906.0),
#   ("SmallDependenceLowGrayLevelEmphasis" (1; #13), 2733.0),
#   ("GrayLevelVariance" (1; #5), 2720.0),
#   ("LowGrayLevelEmphasis" (1; #10), 2508.0),
#   ("LargeDependenceLowGrayLevelEmphasis" (1; #9), 2489.0),
#   ("SmallDependenceEmphasis" (1; #11), 2288.0),
#   ("DependenceVariance" (1; #3), 2266.0),
#   ("DependenceNonUniformityNormalized" (1; #2), 1743.0),
#   ("LargeDependenceEmphasis" (1; #7), 1710.0),
#   ("DependenceNonUniformity" (1; #1), 1670.0)]}

# %%
# Model self evaluation
model.make_inspector().evaluation()
# Out:
# Evaluation(num_examples=7617, accuracy=0.8579397697713576, loss=0.597384550514618, rmse=None, ndcg=None, aucs=None, auuc=None, qini=None)

# %%
logs = model.make_inspector().training_logs()

plt.figure(figsize=(12, 4))
plt.subplot(1, 2, 1)
plt.plot([log.num_trees for log in logs], [log.evaluation.accuracy for log in logs])
plt.xlabel("Number of trees")
plt.ylabel("Accuracy (out-of-bag)")
plt.subplot(1, 2, 2)
plt.plot([log.num_trees for log in logs], [log.evaluation.loss for log in logs])
plt.xlabel("Number of trees")
plt.ylabel("Logloss (out-of-bag)")
plt.show()

# %% [markdown]
# Calculate the score of our hold-out validation dataset

# %%
predictions = model.predict(val_ds)
y_true      = validation_data["label"]

from sklearn.metrics import roc_auc_score
ROC_AUC = roc_auc_score(y_true, predictions)
print("The ROC AUC score is %.5f" % ROC_AUC )
# Out:
# 1/2 [==============>...............] - ETA: 0s
# 2/2 [==============================] - 0s 4ms/step
# The ROC AUC score is 0.99791

# %%
# Compute binary classification metrics with sklearn
import numpy as np
from sklearn.metrics import (
    accuracy_score,
    precision_score,
    recall_score,
    f1_score,
    roc_auc_score,
    average_precision_score,
    confusion_matrix,
    classification_report,
    matthews_corrcoef,
    log_loss,
    brier_score_loss,
)

# Get predictions (probabilities or class labels)
preds = model.predict(test_ds)
# If model outputs probabilities, convert to labels by threshold 0.5
if preds.ndim == 2:
    # For TFDF classification, preds may be class probabilities with shape (N, 2)
    if preds.shape[1] == 2:
        pos_probs = preds[:, 1]
    else:
        # If single-probability column (positive class)
        pos_probs = preds[:, -1]
    y_pred = (pos_probs >= 0.5).astype(int)
else:
    # Already class labels
    y_pred = preds.astype(int)
    pos_probs = None

# Ground truth labels (must be 0/1 integers)
y_true = test_data["label"].astype(int).to_numpy()

# Core metrics
metrics = {}
metrics["accuracy"] = accuracy_score(y_true, y_pred)
metrics["precision"] = precision_score(y_true, y_pred, zero_division=0)
metrics["recall"] = recall_score(y_true, y_pred, zero_division=0)
metrics["f1"] = f1_score(y_true, y_pred, zero_division=0)
metrics["mcc"] = matthews_corrcoef(y_true, y_pred)

# Probabilistic metrics (only if we have probabilities)
if pos_probs is not None:
    metrics["roc_auc"] = roc_auc_score(y_true, pos_probs)
    metrics["pr_auc"] = average_precision_score(y_true, pos_probs)
    metrics["log_loss"] = log_loss(y_true, pos_probs, labels=[0,1])
    metrics["brier_score"] = brier_score_loss(y_true, pos_probs)

# Confusion matrix and detailed report
cm = confusion_matrix(y_true, y_pred, labels=[0,1])
report = classification_report(y_true, y_pred, digits=4)

print("Sklearn binary metrics:")
for k, v in metrics.items():
    print(f"{k}: {v:.4f}")
print("\nConfusion matrix:\n", cm)
print("\nClassification report:\n", report)
# Out:
# 1/3 [=========>....................] - ETA: 0s
# 3/3 [==============================] - 0s 10ms/step
# Sklearn binary metrics:
# accuracy: 0.9680
# precision: 0.9053
# recall: 0.7577
# f1: 0.8249
# mcc: 0.8114
# roc_auc: 0.9544
# pr_auc: 0.8678
# log_loss: 0.1475
# brier_score: 0.0270
#
# Confusion matrix:
#  [[2038   18]
#  [  55  172]]
#
# Classification report:
#                precision    recall  f1-score   support
#
#            0     0.9737    0.9912    0.9824      2056
#            1     0.9053    0.7577    0.8249       227
#
#     accuracy                         0.9680      2283
#    macro avg     0.9395    0.8745    0.9037      2283
# weighted avg     0.9669    0.9680    0.9667      2283
