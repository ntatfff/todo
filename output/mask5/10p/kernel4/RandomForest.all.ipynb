# %%
# Import packages and modules
import numpy  as np
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow_decision_forests as tfdf

from sklearn.model_selection import train_test_split
# Out:
# 2026-09-12 10:40:23.939554: I tensorflow/core/util/port.cc:113] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2026-09-12 10:40:24.278918: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2026-09-12 10:40:28.911288: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
# Check the version of TensorFlow Decision Forests
print("Found TensorFlow Decision Forests v" + tfdf.__version__)
# Out:
# Found TensorFlow Decision Forests v1.9.1

# %%
datasetPath = "dataset/10p/all/kernel3/"

# %%
# Parameters
datasetPath = "dataset/mask5/10p/all/kernel4/"

# %%
# train/validation/test = 70/10/20
train_data = pd.read_csv(f"{datasetPath}dataset.train.csv")
validation_data = pd.read_csv(f"{datasetPath}dataset.validation.csv")
test_data = pd.read_csv(f"{datasetPath}dataset.test.csv")

# %%
from sklearn.utils.class_weight import compute_class_weight

# tinh class weight tren tap train
classes = np.array([0, 1])
weights = compute_class_weight(class_weight="balanced", classes=classes, y=train_data["label"])
class_weight = {0: weights[0], 1: weights[1]}

# gan sample_weight cho tung dong
train_data["sample_weight"] = train_data["label"].map(class_weight)
validation_data["sample_weight"] = validation_data["label"].map(class_weight)
test_data["sample_weight"] = test_data["label"].map(class_weight)

# Convert the dataset into a TensorFlow dataset.
train_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    train_data, label="label", weight="sample_weight"
)         
val_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    validation_data, label="label", weight="sample_weight"
)
test_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    test_data, label="label", weight="sample_weight"
)
# Out:
# 2026-09-12 10:40:41.860904: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:984] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2026-09-12 10:40:41.862970: W tensorflow/core/common_runtime/gpu/gpu_device.cc:2251] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...

# %%
import keras

# %%
# %%time

# Train a Random Forest model.
model = tfdf.keras.RandomForestModel()

# Add evaluation metrics
model.compile(
    metrics=["accuracy"]
)
model.fit(x=train_ds)

# # Train a Gradient Boosted Trees model.
# model = tfdf.keras.GradientBoostedTreesModel(num_trees=1500)
# model.fit(train_ds)
# Out:
# Use /tmp/tmpcwyg1vmr as temporary training directory
# Reading training dataset...
# Training dataset read in 0:00:03.346221. Found 7617 examples.
# Training model...
# Model trained in 0:00:00.740647
# Compiling model...
# [INFO 26-09-12 10:40:46.1630 UTC kernel.cc:1233] Loading model from path /tmp/tmpcwyg1vmr/model/ with prefix ddc59f15a67346eb
# [INFO 26-09-12 10:40:46.2320 UTC decision_forest.cc:734] Model loaded with 300 root(s), 60146 node(s), and 93 input feature(s).
# [INFO 26-09-12 10:40:46.2320 UTC abstract_model.cc:1362] Engine "RandomForestOptPred" built
# [INFO 26-09-12 10:40:46.2320 UTC kernel.cc:1061] Use fast generic engine
# Model compiled.
# CPU times: user 13.3 s, sys: 162 ms, total: 13.5 s
# Wall time: 7.7 s

# %%
# Evaluate the model
evaluate = model.evaluate(val_ds, return_dict=True)
print()

for name, value in evaluate.items():
    print(f"{name}: {value:.4f}")
# Out:
# WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 1/2 [==============>...............] - ETA: 3s - loss: 0.0000e+00 - accuracy: 0.9950
# 2/2 [==============================] - 3s 9ms/step - loss: 0.0000e+00 - accuracy: 0.9935
# loss: 0.0000
# accuracy: 0.9935

# %%
# Model Summary
model.summary()
# Out:
# Model: "random_forest_model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
# =================================================================
# Total params: 1 (1.00 Byte)
# Trainable params: 0 (0.00 Byte)
# Non-trainable params: 1 (1.00 Byte)
# _________________________________________________________________
# Type: "RANDOM_FOREST"
# Task: CLASSIFICATION
# Label: "__LABEL"
#
# Input Features (93):
# 	10Percentile
# 	90Percentile
# 	Autocorrelation
# 	Busyness
# 	ClusterProminence
# 	ClusterShade
# 	ClusterTendency
# 	Coarseness
# 	Complexity
# 	Contrast
# 	Contrast.1
# 	Correlation
# 	DependenceEntropy
# 	DependenceNonUniformity
# 	DependenceNonUniformityNormalized
# 	DependenceVariance
# 	DifferenceAverage
# 	DifferenceEntropy
# 	DifferenceVariance
# 	Energy
# 	Entropy
# 	GrayLevelNonUniformity
# 	GrayLevelNonUniformity.1
# 	GrayLevelNonUniformity.2
# 	GrayLevelNonUniformityNormalized
# 	GrayLevelNonUniformityNormalized.1
# 	GrayLevelVariance
# 	GrayLevelVariance.1
# 	GrayLevelVariance.2
# 	HighGrayLevelEmphasis
# 	HighGrayLevelRunEmphasis
# 	HighGrayLevelZoneEmphasis
# 	Id
# 	Idm
# 	Idmn
# 	Idn
# 	Imc1
# 	Imc2
# 	InterquartileRange
# 	InverseVariance
# 	JointAverage
# 	JointEnergy
# 	JointEntropy
# 	Kurtosis
# 	LargeAreaEmphasis
# 	LargeAreaHighGrayLevelEmphasis
# 	LargeAreaLowGrayLevelEmphasis
# 	LargeDependenceEmphasis
# 	LargeDependenceHighGrayLevelEmphasis
# 	LargeDependenceLowGrayLevelEmphasis
# 	LongRunEmphasis
# 	LongRunHighGrayLevelEmphasis
# 	LongRunLowGrayLevelEmphasis
# 	LowGrayLevelEmphasis
# 	LowGrayLevelRunEmphasis
# 	LowGrayLevelZoneEmphasis
# 	MCC
# 	Maximum
# 	MaximumProbability
# 	Mean
# 	MeanAbsoluteDeviation
# 	Median
# 	Minimum
# 	Range
# 	RobustMeanAbsoluteDeviation
# 	RootMeanSquared
# 	RunEntropy
# 	RunLengthNonUniformity
# 	RunLengthNonUniformityNormalized
# 	RunPercentage
# 	RunVariance
# 	ShortRunEmphasis
# 	ShortRunHighGrayLevelEmphasis
# 	ShortRunLowGrayLevelEmphasis
# 	SizeZoneNonUniformity
# 	SizeZoneNonUniformityNormalized
# 	Skewness
# 	SmallAreaEmphasis
# 	SmallAreaHighGrayLevelEmphasis
# 	SmallAreaLowGrayLevelEmphasis
# 	SmallDependenceEmphasis
# 	SmallDependenceHighGrayLevelEmphasis
# 	SmallDependenceLowGrayLevelEmphasis
# 	Strength
# 	SumAverage
# 	SumEntropy
# 	SumSquares
# 	TotalEnergy
# 	Uniformity
# 	Variance
# 	ZoneEntropy
# 	ZonePercentage
# 	ZoneVariance
#
# Trained with weights
#
# Variable Importance: INV_MEAN_MIN_DEPTH:
#     1.         "LongRunHighGrayLevelEmphasis"  0.133253 ################
#     2.             "GrayLevelNonUniformity.2"  0.126886 ############
#     3. "LargeDependenceHighGrayLevelEmphasis"  0.125659 ###########
#     4.                                 "Mean"  0.122557 #########
#     5.                           "Coarseness"  0.121514 #########
#     6.                         "90Percentile"  0.120703 ########
#     7.                               "Median"  0.119859 ########
#     8.            "HighGrayLevelZoneEmphasis"  0.119586 #######
#     9.                             "Busyness"  0.119390 #######
#    10.                "HighGrayLevelEmphasis"  0.118749 #######
#    11.                         "JointAverage"  0.118025 #######
#    12.                      "Autocorrelation"  0.117600 ######
#    13.                           "SumAverage"  0.117392 ######
#    14.       "LargeAreaHighGrayLevelEmphasis"  0.116971 ######
#    15.                               "Energy"  0.116883 ######
#    16.                          "TotalEnergy"  0.116649 ######
#    17.                              "Maximum"  0.115621 #####
#    18.                                  "Idn"  0.115003 #####
#    19.                      "RootMeanSquared"  0.114640 #####
#    20.                                 "Idmn"  0.113683 ####
#    21.                    "DependenceEntropy"  0.113521 ####
#    22.                      "InverseVariance"  0.113240 ####
#    23.        "ShortRunHighGrayLevelEmphasis"  0.113040 ####
#    24.                             "Skewness"  0.112788 ###
#    25.  "SmallDependenceLowGrayLevelEmphasis"  0.112493 ###
#    26.       "SmallAreaHighGrayLevelEmphasis"  0.112428 ###
#    27.                                 "Imc1"  0.111716 ###
#    28.         "ShortRunLowGrayLevelEmphasis"  0.111255 ###
#    29.              "LowGrayLevelRunEmphasis"  0.111205 ###
#    30.                 "LowGrayLevelEmphasis"  0.110965 ##
#    31.          "LongRunLowGrayLevelEmphasis"  0.110538 ##
#    32.  "LargeDependenceLowGrayLevelEmphasis"  0.110485 ##
#    33.             "HighGrayLevelRunEmphasis"  0.110032 ##
#    34.                         "ClusterShade"  0.109989 ##
#    35.                                  "MCC"  0.109562 ##
#    36.                          "Correlation"  0.109528 ##
#    37.             "LowGrayLevelZoneEmphasis"  0.109498 ##
#    38.                                 "Imc2"  0.109416 ##
#    39. "SmallDependenceHighGrayLevelEmphasis"  0.109238 #
#    40.                         "10Percentile"  0.109177 #
#    41.                              "Minimum"  0.108997 #
#    42.              "DependenceNonUniformity"  0.108944 #
#    43.    "DependenceNonUniformityNormalized"  0.108739 #
#    44.                "SizeZoneNonUniformity"  0.108733 #
#    45.        "SmallAreaLowGrayLevelEmphasis"  0.108661 #
#    46.                   "DependenceVariance"  0.108644 #
#    47.              "SmallDependenceEmphasis"  0.108617 #
#    48.               "GrayLevelNonUniformity"  0.108346 #
#    49.                          "RunVariance"  0.108317 #
#    50.                             "Strength"  0.108251 #
#    51.        "LargeAreaLowGrayLevelEmphasis"  0.108223 #
#    52.                       "ZonePercentage"  0.108042 #
#    53.                           "SumEntropy"  0.107973 #
#    54.                             "Kurtosis"  0.107942 #
#    55.              "LargeDependenceEmphasis"  0.107807 #
#    56.                      "LongRunEmphasis"  0.107708 #
#    57.                           "Contrast.1"  0.107658
#    58.                                  "Idm"  0.107645
#    59.                  "GrayLevelVariance.2"  0.107628
#    60.                           "Uniformity"  0.107535
#    61.                                "Range"  0.107471
#    62.             "GrayLevelNonUniformity.1"  0.107449
#    63.                    "DifferenceAverage"  0.107439
#    64.                                   "Id"  0.107427
#    65.                   "DifferenceVariance"  0.107422
#    66.     "GrayLevelNonUniformityNormalized"  0.107357
#    67.                    "SmallAreaEmphasis"  0.107311
#    68.   "GrayLevelNonUniformityNormalized.1"  0.107310
#    69.                             "Contrast"  0.107261
#    70.                    "DifferenceEntropy"  0.107218
#    71.                   "MaximumProbability"  0.107176
#    72.                           "RunEntropy"  0.107121
#    73.                              "Entropy"  0.107067
#    74.                          "ZoneEntropy"  0.106997
#    75.                        "RunPercentage"  0.106993
#    76.      "SizeZoneNonUniformityNormalized"  0.106984
#    77.                          "JointEnergy"  0.106975
#    78.                     "ShortRunEmphasis"  0.106953
#    79.                      "ClusterTendency"  0.106916
#    80.                         "ZoneVariance"  0.106915
#    81.               "RunLengthNonUniformity"  0.106825
#    82.                           "Complexity"  0.106816
#    83.     "RunLengthNonUniformityNormalized"  0.106779
#    84.                    "ClusterProminence"  0.106776
#    85.                   "InterquartileRange"  0.106676
#    86.          "RobustMeanAbsoluteDeviation"  0.106553
#    87.                    "GrayLevelVariance"  0.106493
#    88.                  "GrayLevelVariance.1"  0.106346
#    89.                "MeanAbsoluteDeviation"  0.106313
#    90.                             "Variance"  0.106298
#    91.                           "SumSquares"  0.106243
#    92.                         "JointEntropy"  0.106213
#    93.                    "LargeAreaEmphasis"  0.105983
#
# Variable Importance: NUM_AS_ROOT:
#     1.         "LongRunHighGrayLevelEmphasis" 31.000000 ################
#     2.            "HighGrayLevelZoneEmphasis" 27.000000 #############
#     3.                         "90Percentile" 26.000000 #############
#     4.                                 "Mean" 25.000000 ############
#     5.                "HighGrayLevelEmphasis" 23.000000 ###########
#     6.                          "TotalEnergy" 20.000000 ##########
#     7.                      "Autocorrelation" 16.000000 ########
#     8.                               "Energy" 16.000000 ########
#     9.                         "JointAverage" 16.000000 ########
#    10.                           "SumAverage" 16.000000 ########
#    11.                      "RootMeanSquared" 13.000000 ######
#    12.       "SmallAreaHighGrayLevelEmphasis" 10.000000 ####
#    13.        "ShortRunHighGrayLevelEmphasis"  9.000000 ####
#    14.                              "Maximum"  8.000000 ###
#    15.                               "Median"  6.000000 ##
#    16.             "HighGrayLevelRunEmphasis"  4.000000 #
#    17.             "LowGrayLevelZoneEmphasis"  4.000000 #
#    18.                              "Minimum"  4.000000 #
#    19.         "ShortRunLowGrayLevelEmphasis"  4.000000 #
#    20.              "LowGrayLevelRunEmphasis"  3.000000 #
#    21.                             "Busyness"  2.000000
#    22.                 "LowGrayLevelEmphasis"  2.000000
#    23.        "SmallAreaLowGrayLevelEmphasis"  2.000000
#    24.                         "10Percentile"  1.000000
#    25.                           "Coarseness"  1.000000
#    26.                    "DependenceEntropy"  1.000000
#    27.               "GrayLevelNonUniformity"  1.000000
#    28.     "GrayLevelNonUniformityNormalized"  1.000000
#    29.                                 "Imc1"  1.000000
#    30. "LargeDependenceHighGrayLevelEmphasis"  1.000000
#    31.  "LargeDependenceLowGrayLevelEmphasis"  1.000000
#    32.          "LongRunLowGrayLevelEmphasis"  1.000000
#    33.                                  "MCC"  1.000000
#    34. "SmallDependenceHighGrayLevelEmphasis"  1.000000
#    35.  "SmallDependenceLowGrayLevelEmphasis"  1.000000
#    36.                           "Uniformity"  1.000000
#
# Variable Importance: NUM_NODES:
#     1.                                  "Idn" 1045.000000 ################
#     2.                                 "Idmn" 885.000000 #############
#     3.                             "Skewness" 742.000000 ##########
#     4.             "GrayLevelNonUniformity.2" 674.000000 #########
#     5. "LargeDependenceHighGrayLevelEmphasis" 646.000000 ########
#     6.                           "Coarseness" 613.000000 ########
#     7.                             "Busyness" 571.000000 #######
#     8.                         "ClusterShade" 550.000000 #######
#     9.                              "Maximum" 528.000000 ######
#    10.                               "Median" 521.000000 ######
#    11.         "LongRunHighGrayLevelEmphasis" 498.000000 ######
#    12.                         "90Percentile" 430.000000 ####
#    13.                          "Correlation" 424.000000 ####
#    14.                    "DependenceEntropy" 421.000000 ####
#    15.                                  "MCC" 393.000000 ####
#    16.       "LargeAreaHighGrayLevelEmphasis" 390.000000 ####
#    17.                                 "Imc1" 389.000000 ####
#    18.                             "Kurtosis" 381.000000 ###
#    19.                           "SumAverage" 376.000000 ###
#    20.       "SmallAreaHighGrayLevelEmphasis" 372.000000 ###
#    21.                           "Contrast.1" 369.000000 ###
#    22.                      "Autocorrelation" 362.000000 ###
#    23.                                 "Imc2" 359.000000 ###
#    24.            "HighGrayLevelZoneEmphasis" 358.000000 ###
#    25.                                 "Mean" 346.000000 ###
#    26.        "SmallAreaLowGrayLevelEmphasis" 335.000000 ###
#    27.                         "JointAverage" 334.000000 ###
#    28.             "LowGrayLevelZoneEmphasis" 333.000000 ###
#    29.  "LargeDependenceLowGrayLevelEmphasis" 327.000000 ###
#    30.  "SmallDependenceLowGrayLevelEmphasis" 326.000000 ##
#    31.                             "Strength" 321.000000 ##
#    32.                "HighGrayLevelEmphasis" 314.000000 ##
#    33.                             "Contrast" 312.000000 ##
#    34.          "LongRunLowGrayLevelEmphasis" 310.000000 ##
#    35.                                "Range" 309.000000 ##
#    36.                              "Minimum" 303.000000 ##
#    37.                           "SumEntropy" 301.000000 ##
#    38.                   "DifferenceVariance" 300.000000 ##
#    39.                  "GrayLevelVariance.2" 300.000000 ##
#    40.      "SizeZoneNonUniformityNormalized" 300.000000 ##
#    41. "SmallDependenceHighGrayLevelEmphasis" 298.000000 ##
#    42.                   "DependenceVariance" 297.000000 ##
#    43.                               "Energy" 297.000000 ##
#    44.        "ShortRunHighGrayLevelEmphasis" 290.000000 ##
#    45.                          "TotalEnergy" 289.000000 ##
#    46.        "LargeAreaLowGrayLevelEmphasis" 288.000000 ##
#    47.         "ShortRunLowGrayLevelEmphasis" 287.000000 ##
#    48.              "LowGrayLevelRunEmphasis" 286.000000 ##
#    49.                      "InverseVariance" 282.000000 ##
#    50.                         "10Percentile" 281.000000 ##
#    51.                    "SmallAreaEmphasis" 276.000000 ##
#    52.                "SizeZoneNonUniformity" 271.000000 #
#    53.                 "LowGrayLevelEmphasis" 270.000000 #
#    54.                    "DifferenceAverage" 268.000000 #
#    55.                      "RootMeanSquared" 267.000000 #
#    56.             "HighGrayLevelRunEmphasis" 264.000000 #
#    57.                          "ZoneEntropy" 263.000000 #
#    58.   "GrayLevelNonUniformityNormalized.1" 262.000000 #
#    59.              "SmallDependenceEmphasis" 261.000000 #
#    60.                           "Complexity" 260.000000 #
#    61.                    "DifferenceEntropy" 254.000000 #
#    62.     "GrayLevelNonUniformityNormalized" 254.000000 #
#    63.               "GrayLevelNonUniformity" 252.000000 #
#    64.             "GrayLevelNonUniformity.1" 252.000000 #
#    65.                          "RunVariance" 250.000000 #
#    66.                           "Uniformity" 245.000000 #
#    67.                   "InterquartileRange" 240.000000 #
#    68.    "DependenceNonUniformityNormalized" 232.000000 #
#    69.                   "MaximumProbability" 232.000000 #
#    70.              "DependenceNonUniformity" 225.000000 #
#    71.                          "JointEnergy" 225.000000 #
#    72.                       "ZonePercentage" 225.000000 #
#    73.                                  "Idm" 223.000000 #
#    74.              "LargeDependenceEmphasis" 223.000000 #
#    75.                                   "Id" 222.000000 #
#    76.                           "RunEntropy" 219.000000 #
#    77.                              "Entropy" 214.000000
#    78.          "RobustMeanAbsoluteDeviation" 211.000000
#    79.                    "ClusterProminence" 209.000000
#    80.                      "LongRunEmphasis" 209.000000
#    81.                    "GrayLevelVariance" 202.000000
#    82.                         "JointEntropy" 201.000000
#    83.                      "ClusterTendency" 200.000000
#    84.                         "ZoneVariance" 198.000000
#    85.                  "GrayLevelVariance.1" 197.000000
#    86.                "MeanAbsoluteDeviation" 182.000000
#    87.     "RunLengthNonUniformityNormalized" 181.000000
#    88.               "RunLengthNonUniformity" 177.000000
#    89.                     "ShortRunEmphasis" 177.000000
#    90.                             "Variance" 174.000000
#    91.                        "RunPercentage" 169.000000
#    92.                           "SumSquares" 163.000000
#    93.                    "LargeAreaEmphasis" 161.000000
#
# Variable Importance: SUM_SCORE:
#     1.         "LongRunHighGrayLevelEmphasis" 100774.813502 ################
#     2.                         "90Percentile" 68462.592623 ##########
#     3.            "HighGrayLevelZoneEmphasis" 68075.159365 ##########
#     4.                                 "Mean" 67505.244866 ##########
#     5.                "HighGrayLevelEmphasis" 59061.923339 #########
#     6.                          "TotalEnergy" 51660.994265 ########
#     7. "LargeDependenceHighGrayLevelEmphasis" 50405.274655 #######
#     8.                           "SumAverage" 47138.558552 #######
#     9.                               "Energy" 46787.747408 #######
#    10.                      "Autocorrelation" 46720.988780 #######
#    11.                         "JointAverage" 46519.001804 #######
#    12.             "GrayLevelNonUniformity.2" 41193.757357 ######
#    13.                      "RootMeanSquared" 38447.029002 #####
#    14.                                  "Idn" 34891.684241 #####
#    15.                               "Median" 33928.305155 #####
#    16.                              "Maximum" 33817.541145 #####
#    17.                           "Coarseness" 31294.280533 ####
#    18.       "SmallAreaHighGrayLevelEmphasis" 30204.430988 ####
#    19.                             "Busyness" 29638.198151 ####
#    20.        "ShortRunHighGrayLevelEmphasis" 29158.298553 ####
#    21.                                 "Idmn" 28042.243875 ####
#    22.       "LargeAreaHighGrayLevelEmphasis" 24136.290030 ###
#    23.                    "DependenceEntropy" 17676.015217 ##
#    24.                             "Skewness" 17440.092543 ##
#    25.         "ShortRunLowGrayLevelEmphasis" 16858.526890 ##
#    26.             "HighGrayLevelRunEmphasis" 15875.172084 ##
#    27.              "LowGrayLevelRunEmphasis" 15323.161987 ##
#    28.             "LowGrayLevelZoneEmphasis" 14491.018066 #
#    29.                      "InverseVariance" 14016.777625 #
#    30.                                 "Imc1" 13188.016355 #
#    31.  "SmallDependenceLowGrayLevelEmphasis" 12646.458372 #
#    32.                 "LowGrayLevelEmphasis" 12185.155337 #
#    33.          "LongRunLowGrayLevelEmphasis" 11630.741302 #
#    34.  "LargeDependenceLowGrayLevelEmphasis" 11598.917741 #
#    35.                         "ClusterShade" 11054.177511 #
#    36.                          "Correlation" 10243.826013 #
#    37.                              "Minimum" 9894.942103 #
#    38.                                 "Imc2" 9875.847295 #
#    39. "SmallDependenceHighGrayLevelEmphasis" 9543.992627 #
#    40.        "SmallAreaLowGrayLevelEmphasis" 9523.303217 #
#    41.                                  "MCC" 9259.068917 #
#    42.                         "10Percentile" 9140.426352 #
#    43.                           "SumEntropy" 8570.360512 #
#    44.                "SizeZoneNonUniformity" 8308.451477
#    45.                           "Contrast.1" 8061.665587
#    46.                   "DependenceVariance" 7731.244230
#    47.              "DependenceNonUniformity" 7474.326015
#    48.    "DependenceNonUniformityNormalized" 7450.407225
#    49.              "SmallDependenceEmphasis" 7399.218926
#    50.               "GrayLevelNonUniformity" 7293.406950
#    51.                             "Strength" 7251.534103
#    52.        "LargeAreaLowGrayLevelEmphasis" 7131.382396
#    53.                       "ZonePercentage" 6476.537022
#    54.                          "RunVariance" 6327.356837
#    55.                             "Contrast" 6176.161276
#    56.                    "DifferenceAverage" 6094.979929
#    57.                             "Kurtosis" 6018.475192
#    58.                    "DifferenceEntropy" 5766.549353
#    59.   "GrayLevelNonUniformityNormalized.1" 5749.367349
#    60.                                  "Idm" 5698.404648
#    61.                   "DifferenceVariance" 5624.952741
#    62.                           "Uniformity" 5596.912439
#    63.      "SizeZoneNonUniformityNormalized" 5588.685069
#    64.                  "GrayLevelVariance.2" 5583.863530
#    65.             "GrayLevelNonUniformity.1" 5580.380119
#    66.                    "SmallAreaEmphasis" 5553.736895
#    67.                           "RunEntropy" 5484.749924
#    68.              "LargeDependenceEmphasis" 5467.206698
#    69.                          "ZoneEntropy" 5444.891330
#    70.                                "Range" 5408.406059
#    71.                      "LongRunEmphasis" 5289.438929
#    72.                              "Entropy" 5257.849713
#    73.     "GrayLevelNonUniformityNormalized" 5203.077901
#    74.                                   "Id" 5059.880967
#    75.                   "MaximumProbability" 4906.654012
#    76.                          "JointEnergy" 4382.827306
#    77.                      "ClusterTendency" 4367.770359
#    78.                        "RunPercentage" 4330.059307
#    79.                     "ShortRunEmphasis" 4299.040971
#    80.                         "ZoneVariance" 4186.738741
#    81.               "RunLengthNonUniformity" 4078.177782
#    82.                           "Complexity" 3888.271039
#    83.                  "GrayLevelVariance.1" 3627.741870
#    84.                   "InterquartileRange" 3599.727371
#    85.                    "GrayLevelVariance" 3561.972431
#    86.                    "ClusterProminence" 3483.671929
#    87.     "RunLengthNonUniformityNormalized" 3404.121595
#    88.          "RobustMeanAbsoluteDeviation" 3390.045901
#    89.                             "Variance" 3375.040840
#    90.                "MeanAbsoluteDeviation" 3334.542808
#    91.                         "JointEntropy" 3235.628536
#    92.                           "SumSquares" 2645.466702
#    93.                    "LargeAreaEmphasis" 2307.988245
#
#
#
# Winner takes all: true
# Out-of-bag evaluation: accuracy:0.877634 logloss:0.337551
# Number of trees: 300
# Total number of nodes: 60146
#
# Number of nodes by tree:
# Count: 300 Average: 200.487 StdDev: 12.2383
# Min: 165 Max: 233 Ignored: 0
# ----------------------------------------------
# [ 165, 168)  2   0.67%   0.67%
# [ 168, 171)  1   0.33%   1.00%
# [ 171, 175)  1   0.33%   1.33%
# [ 175, 178)  5   1.67%   3.00% #
# [ 178, 182) 11   3.67%   6.67% ###
# [ 182, 185)  7   2.33%   9.00% ##
# [ 185, 189) 21   7.00%  16.00% #####
# [ 189, 192) 20   6.67%  22.67% #####
# [ 192, 196) 38  12.67%  35.33% #########
# [ 196, 199) 23   7.67%  43.00% #####
# [ 199, 202) 34  11.33%  54.33% ########
# [ 202, 206) 42  14.00%  68.33% ##########
# [ 206, 209) 16   5.33%  73.67% ####
# [ 209, 213) 26   8.67%  82.33% ######
# [ 213, 216) 22   7.33%  89.67% #####
# [ 216, 220) 16   5.33%  95.00% ####
# [ 220, 223)  5   1.67%  96.67% #
# [ 223, 227)  5   1.67%  98.33% #
# [ 227, 230)  3   1.00%  99.33% #
# [ 230, 233]  2   0.67% 100.00%
#
# Depth by leafs:
# Count: 30223 Average: 8.50395 StdDev: 2.5216
# Min: 2 Max: 15 Ignored: 0
# ----------------------------------------------
# [  2,  3)   29   0.10%   0.10%
# [  3,  4)  406   1.34%   1.44% #
# [  4,  5)  984   3.26%   4.70% ##
# [  5,  6) 2027   6.71%  11.40% ####
# [  6,  7) 3332  11.02%  22.43% #######
# [  7,  8) 4183  13.84%  36.27% #########
# [  8,  9) 4641  15.36%  51.62% ##########
# [  9, 10) 4486  14.84%  66.47% ##########
# [ 10, 11) 3699  12.24%  78.70% ########
# [ 11, 12) 2675   8.85%  87.56% ######
# [ 12, 13) 1781   5.89%  93.45% ####
# [ 13, 14) 1002   3.32%  96.76% ##
# [ 14, 15)  590   1.95%  98.72% #
# [ 15, 15]  388   1.28% 100.00% #
#
# Number of training obs by leaf:
# Count: 30223 Average: 75.608 StdDev: 254.216
# Min: 5 Max: 3223 Ignored: 0
# ----------------------------------------------
# [    5,  165) 27614  91.37%  91.37% ##########
# [  165,  326)  1040   3.44%  94.81%
# [  326,  487)   379   1.25%  96.06%
# [  487,  648)   254   0.84%  96.90%
# [  648,  809)   203   0.67%  97.57%
# [  809,  970)   119   0.39%  97.97%
# [  970, 1131)   114   0.38%  98.35%
# [ 1131, 1292)    82   0.27%  98.62%
# [ 1292, 1453)    79   0.26%  98.88%
# [ 1453, 1614)    77   0.25%  99.13%
# [ 1614, 1775)    63   0.21%  99.34%
# [ 1775, 1936)    67   0.22%  99.56%
# [ 1936, 2097)    43   0.14%  99.71%
# [ 2097, 2258)    34   0.11%  99.82%
# [ 2258, 2419)    16   0.05%  99.87%
# [ 2419, 2580)    15   0.05%  99.92%
# [ 2580, 2741)     8   0.03%  99.95%
# [ 2741, 2902)     8   0.03%  99.97%
# [ 2902, 3063)     5   0.02%  99.99%
# [ 3063, 3223]     3   0.01% 100.00%
#
# Attribute in nodes:
# 	1045 : Idn [NUMERICAL]
# 	885 : Idmn [NUMERICAL]
# 	742 : Skewness [NUMERICAL]
# 	674 : GrayLevelNonUniformity.2 [NUMERICAL]
# 	646 : LargeDependenceHighGrayLevelEmphasis [NUMERICAL]
# 	613 : Coarseness [NUMERICAL]
# 	571 : Busyness [NUMERICAL]
# 	550 : ClusterShade [NUMERICAL]
# 	528 : Maximum [NUMERICAL]
# 	521 : Median [NUMERICAL]
# 	498 : LongRunHighGrayLevelEmphasis [NUMERICAL]
# 	430 : 90Percentile [NUMERICAL]
# 	424 : Correlation [NUMERICAL]
# 	421 : DependenceEntropy [NUMERICAL]
# 	393 : MCC [NUMERICAL]
# 	390 : LargeAreaHighGrayLevelEmphasis [NUMERICAL]
# 	389 : Imc1 [NUMERICAL]
# 	381 : Kurtosis [NUMERICAL]
# 	376 : SumAverage [NUMERICAL]
# 	372 : SmallAreaHighGrayLevelEmphasis [NUMERICAL]
# 	369 : Contrast.1 [NUMERICAL]
# 	362 : Autocorrelation [NUMERICAL]
# 	359 : Imc2 [NUMERICAL]
# 	358 : HighGrayLevelZoneEmphasis [NUMERICAL]
# 	346 : Mean [NUMERICAL]
# 	335 : SmallAreaLowGrayLevelEmphasis [NUMERICAL]
# 	334 : JointAverage [NUMERICAL]
# 	333 : LowGrayLevelZoneEmphasis [NUMERICAL]
# 	327 : LargeDependenceLowGrayLevelEmphasis [NUMERICAL]
# 	326 : SmallDependenceLowGrayLevelEmphasis [NUMERICAL]
# 	321 : Strength [NUMERICAL]
# 	314 : HighGrayLevelEmphasis [NUMERICAL]
# 	312 : Contrast [NUMERICAL]
# 	310 : LongRunLowGrayLevelEmphasis [NUMERICAL]
# 	309 : Range [NUMERICAL]
# 	303 : Minimum [NUMERICAL]
# 	301 : SumEntropy [NUMERICAL]
# 	300 : SizeZoneNonUniformityNormalized [NUMERICAL]
# 	300 : GrayLevelVariance.2 [NUMERICAL]
# 	300 : DifferenceVariance [NUMERICAL]
# 	298 : SmallDependenceHighGrayLevelEmphasis [NUMERICAL]
# 	297 : Energy [NUMERICAL]
# 	297 : DependenceVariance [NUMERICAL]
# 	290 : ShortRunHighGrayLevelEmphasis [NUMERICAL]
# 	289 : TotalEnergy [NUMERICAL]
# 	288 : LargeAreaLowGrayLevelEmphasis [NUMERICAL]
# 	287 : ShortRunLowGrayLevelEmphasis [NUMERICAL]
# 	286 : LowGrayLevelRunEmphasis [NUMERICAL]
# 	282 : InverseVariance [NUMERICAL]
# 	281 : 10Percentile [NUMERICAL]
# 	276 : SmallAreaEmphasis [NUMERICAL]
# 	271 : SizeZoneNonUniformity [NUMERICAL]
# 	270 : LowGrayLevelEmphasis [NUMERICAL]
# 	268 : DifferenceAverage [NUMERICAL]
# 	267 : RootMeanSquared [NUMERICAL]
# 	264 : HighGrayLevelRunEmphasis [NUMERICAL]
# 	263 : ZoneEntropy [NUMERICAL]
# 	262 : GrayLevelNonUniformityNormalized.1 [NUMERICAL]
# 	261 : SmallDependenceEmphasis [NUMERICAL]
# 	260 : Complexity [NUMERICAL]
# 	254 : GrayLevelNonUniformityNormalized [NUMERICAL]
# 	254 : DifferenceEntropy [NUMERICAL]
# 	252 : GrayLevelNonUniformity.1 [NUMERICAL]
# 	252 : GrayLevelNonUniformity [NUMERICAL]
# 	250 : RunVariance [NUMERICAL]
# 	245 : Uniformity [NUMERICAL]
# 	240 : InterquartileRange [NUMERICAL]
# 	232 : MaximumProbability [NUMERICAL]
# 	232 : DependenceNonUniformityNormalized [NUMERICAL]
# 	225 : ZonePercentage [NUMERICAL]
# 	225 : JointEnergy [NUMERICAL]
# 	225 : DependenceNonUniformity [NUMERICAL]
# 	223 : LargeDependenceEmphasis [NUMERICAL]
# 	223 : Idm [NUMERICAL]
# 	222 : Id [NUMERICAL]
# 	219 : RunEntropy [NUMERICAL]
# 	214 : Entropy [NUMERICAL]
# 	211 : RobustMeanAbsoluteDeviation [NUMERICAL]
# 	209 : LongRunEmphasis [NUMERICAL]
# 	209 : ClusterProminence [NUMERICAL]
# 	202 : GrayLevelVariance [NUMERICAL]
# 	201 : JointEntropy [NUMERICAL]
# 	200 : ClusterTendency [NUMERICAL]
# 	198 : ZoneVariance [NUMERICAL]
# 	197 : GrayLevelVariance.1 [NUMERICAL]
# 	182 : MeanAbsoluteDeviation [NUMERICAL]
# 	181 : RunLengthNonUniformityNormalized [NUMERICAL]
# 	177 : ShortRunEmphasis [NUMERICAL]
# 	177 : RunLengthNonUniformity [NUMERICAL]
# 	174 : Variance [NUMERICAL]
# 	169 : RunPercentage [NUMERICAL]
# 	163 : SumSquares [NUMERICAL]
# 	161 : LargeAreaEmphasis [NUMERICAL]
#
# Attribute in nodes with depth <= 0:
# 	31 : LongRunHighGrayLevelEmphasis [NUMERICAL]
# 	27 : HighGrayLevelZoneEmphasis [NUMERICAL]
# 	26 : 90Percentile [NUMERICAL]
# 	25 : Mean [NUMERICAL]
# 	23 : HighGrayLevelEmphasis [NUMERICAL]
# 	20 : TotalEnergy [NUMERICAL]
# 	16 : SumAverage [NUMERICAL]
# 	16 : JointAverage [NUMERICAL]
# 	16 : Energy [NUMERICAL]
# 	16 : Autocorrelation [NUMERICAL]
# 	13 : RootMeanSquared [NUMERICAL]
# 	10 : SmallAreaHighGrayLevelEmphasis [NUMERICAL]
# 	9 : ShortRunHighGrayLevelEmphasis [NUMERICAL]
# 	8 : Maximum [NUMERICAL]
# 	6 : Median [NUMERICAL]
# 	4 : ShortRunLowGrayLevelEmphasis [NUMERICAL]
# 	4 : Minimum [NUMERICAL]
# 	4 : LowGrayLevelZoneEmphasis [NUMERICAL]
# 	4 : HighGrayLevelRunEmphasis [NUMERICAL]
# 	3 : LowGrayLevelRunEmphasis [NUMERICAL]
# 	2 : SmallAreaLowGrayLevelEmphasis [NUMERICAL]
# 	2 : LowGrayLevelEmphasis [NUMERICAL]
# 	2 : Busyness [NUMERICAL]
# 	1 : Uniformity [NUMERICAL]
# 	1 : SmallDependenceLowGrayLevelEmphasis [NUMERICAL]
# 	1 : SmallDependenceHighGrayLevelEmphasis [NUMERICAL]
# 	1 : MCC [NUMERICAL]
# 	1 : LongRunLowGrayLevelEmphasis [NUMERICAL]
# 	1 : LargeDependenceLowGrayLevelEmphasis [NUMERICAL]
# 	1 : LargeDependenceHighGrayLevelEmphasis [NUMERICAL]
# 	1 : Imc1 [NUMERICAL]
# 	1 : GrayLevelNonUniformityNormalized [NUMERICAL]
# 	1 : GrayLevelNonUniformity [NUMERICAL]
# 	1 : DependenceEntropy [NUMERICAL]
# 	1 : Coarseness [NUMERICAL]
# 	1 : 10Percentile [NUMERICAL]
#
# Attribute in nodes with depth <= 1:
# 	83 : LongRunHighGrayLevelEmphasis [NUMERICAL]
# 	58 : Mean [NUMERICAL]
# 	53 : SumAverage [NUMERICAL]
# 	48 : HighGrayLevelEmphasis [NUMERICAL]
# 	48 : Autocorrelation [NUMERICAL]
# 	44 : JointAverage [NUMERICAL]
# 	41 : Median [NUMERICAL]
# 	37 : Energy [NUMERICAL]
# 	36 : HighGrayLevelZoneEmphasis [NUMERICAL]
# 	33 : TotalEnergy [NUMERICAL]
# 	33 : 90Percentile [NUMERICAL]
# 	31 : LargeDependenceHighGrayLevelEmphasis [NUMERICAL]
# 	28 : GrayLevelNonUniformity.2 [NUMERICAL]
# 	27 : RootMeanSquared [NUMERICAL]
# 	25 : LargeAreaHighGrayLevelEmphasis [NUMERICAL]
# 	23 : ShortRunHighGrayLevelEmphasis [NUMERICAL]
# 	22 : HighGrayLevelRunEmphasis [NUMERICAL]
# 	22 : Coarseness [NUMERICAL]
# 	21 : ShortRunLowGrayLevelEmphasis [NUMERICAL]
# 	19 : Busyness [NUMERICAL]
# 	16 : SmallAreaHighGrayLevelEmphasis [NUMERICAL]
# 	15 : SmallDependenceLowGrayLevelEmphasis [NUMERICAL]
# 	14 : Maximum [NUMERICAL]
# 	14 : LowGrayLevelEmphasis [NUMERICAL]
# 	14 : InverseVariance [NUMERICAL]
# 	13 : LowGrayLevelRunEmphasis [NUMERICAL]
# 	10 : LongRunLowGrayLevelEmphasis [NUMERICAL]
# 	9 : SmallAreaLowGrayLevelEmphasis [NUMERICAL]
# 	8 : 10Percentile [NUMERICAL]
# 	7 : LowGrayLevelZoneEmphasis [NUMERICAL]
# 	7 : LargeDependenceLowGrayLevelEmphasis [NUMERICAL]
# 	4 : ZonePercentage [NUMERICAL]
# 	4 : Minimum [NUMERICAL]
# 	4 : LargeAreaLowGrayLevelEmphasis [NUMERICAL]
# 	4 : DependenceNonUniformity [NUMERICAL]
# 	4 : DependenceEntropy [NUMERICAL]
# 	3 : SmallDependenceEmphasis [NUMERICAL]
# 	2 : SmallDependenceHighGrayLevelEmphasis [NUMERICAL]
# 	2 : SizeZoneNonUniformity [NUMERICAL]
# 	2 : MCC [NUMERICAL]
# 	2 : Imc1 [NUMERICAL]
# 	1 : Uniformity [NUMERICAL]
# 	1 : SmallAreaEmphasis [NUMERICAL]
# 	1 : RunVariance [NUMERICAL]
# 	1 : LongRunEmphasis [NUMERICAL]
# 	1 : LargeDependenceEmphasis [NUMERICAL]
# 	1 : Idm [NUMERICAL]
# 	1 : GrayLevelNonUniformityNormalized [NUMERICAL]
# 	1 : GrayLevelNonUniformity [NUMERICAL]
# 	1 : DifferenceEntropy [NUMERICAL]
# 	1 : DependenceNonUniformityNormalized [NUMERICAL]
#
# Attribute in nodes with depth <= 2:
# 	130 : LongRunHighGrayLevelEmphasis [NUMERICAL]
# 	90 : LargeDependenceHighGrayLevelEmphasis [NUMERICAL]
# 	88 : Mean [NUMERICAL]
# 	87 : GrayLevelNonUniformity.2 [NUMERICAL]
# 	85 : SumAverage [NUMERICAL]
# 	81 : Median [NUMERICAL]
# 	77 : Autocorrelation [NUMERICAL]
# 	72 : JointAverage [NUMERICAL]
# 	68 : Coarseness [NUMERICAL]
# 	67 : HighGrayLevelEmphasis [NUMERICAL]
# 	65 : Energy [NUMERICAL]
# 	61 : Skewness [NUMERICAL]
# 	51 : TotalEnergy [NUMERICAL]
# 	50 : Busyness [NUMERICAL]
# 	49 : 90Percentile [NUMERICAL]
# 	48 : HighGrayLevelZoneEmphasis [NUMERICAL]
# 	46 : LargeAreaHighGrayLevelEmphasis [NUMERICAL]
# 	41 : ShortRunLowGrayLevelEmphasis [NUMERICAL]
# 	41 : ShortRunHighGrayLevelEmphasis [NUMERICAL]
# 	41 : RootMeanSquared [NUMERICAL]
# 	38 : InverseVariance [NUMERICAL]
# 	33 : HighGrayLevelRunEmphasis [NUMERICAL]
# 	31 : SmallDependenceLowGrayLevelEmphasis [NUMERICAL]
# 	31 : LowGrayLevelEmphasis [NUMERICAL]
# 	30 : Maximum [NUMERICAL]
# 	29 : LongRunLowGrayLevelEmphasis [NUMERICAL]
# 	27 : DependenceEntropy [NUMERICAL]
# 	25 : ClusterShade [NUMERICAL]
# 	23 : LowGrayLevelRunEmphasis [NUMERICAL]
# 	21 : SmallAreaHighGrayLevelEmphasis [NUMERICAL]
# 	20 : Imc1 [NUMERICAL]
# 	19 : LowGrayLevelZoneEmphasis [NUMERICAL]
# 	19 : LargeDependenceLowGrayLevelEmphasis [NUMERICAL]
# 	17 : LargeAreaLowGrayLevelEmphasis [NUMERICAL]
# 	16 : Idn [NUMERICAL]
# 	15 : MCC [NUMERICAL]
# 	15 : GrayLevelNonUniformity [NUMERICAL]
# 	13 : DependenceVariance [NUMERICAL]
# 	12 : SmallDependenceEmphasis [NUMERICAL]
# 	12 : SmallAreaLowGrayLevelEmphasis [NUMERICAL]
# 	12 : Minimum [NUMERICAL]
# 	12 : DependenceNonUniformityNormalized [NUMERICAL]
# 	12 : DependenceNonUniformity [NUMERICAL]
# 	11 : LongRunEmphasis [NUMERICAL]
# 	11 : Correlation [NUMERICAL]
# 	11 : 10Percentile [NUMERICAL]
# 	9 : Strength [NUMERICAL]
# 	9 : SmallDependenceHighGrayLevelEmphasis [NUMERICAL]
# 	9 : SizeZoneNonUniformity [NUMERICAL]
# 	9 : Idmn [NUMERICAL]
# 	9 : GrayLevelNonUniformityNormalized [NUMERICAL]
# 	9 : DifferenceVariance [NUMERICAL]
# 	8 : Uniformity [NUMERICAL]
# 	8 : SumEntropy [NUMERICAL]
# 	8 : GrayLevelNonUniformity.1 [NUMERICAL]
# 	7 : ZonePercentage [NUMERICAL]
# 	7 : ShortRunEmphasis [NUMERICAL]
# 	7 : RunVariance [NUMERICAL]
# 	7 : LargeDependenceEmphasis [NUMERICAL]
# 	7 : Kurtosis [NUMERICAL]
# 	7 : Imc2 [NUMERICAL]
# 	6 : ZoneVariance [NUMERICAL]
# 	6 : MaximumProbability [NUMERICAL]
# 	6 : Id [NUMERICAL]
# 	6 : GrayLevelVariance.2 [NUMERICAL]
# 	5 : SmallAreaEmphasis [NUMERICAL]
# 	5 : RunPercentage [NUMERICAL]
# 	5 : RunLengthNonUniformityNormalized [NUMERICAL]
# 	5 : RunEntropy [NUMERICAL]
# 	5 : JointEnergy [NUMERICAL]
# 	5 : Idm [NUMERICAL]
# 	5 : DifferenceAverage [NUMERICAL]
# 	4 : RunLengthNonUniformity [NUMERICAL]
# 	4 : GrayLevelVariance [NUMERICAL]
# 	4 : GrayLevelNonUniformityNormalized.1 [NUMERICAL]
# 	4 : Entropy [NUMERICAL]
# 	3 : RobustMeanAbsoluteDeviation [NUMERICAL]
# 	3 : Contrast.1 [NUMERICAL]
# 	2 : ZoneEntropy [NUMERICAL]
# 	2 : SizeZoneNonUniformityNormalized [NUMERICAL]
# 	2 : DifferenceEntropy [NUMERICAL]
# 	2 : Complexity [NUMERICAL]
# 	1 : Variance [NUMERICAL]
# 	1 : SumSquares [NUMERICAL]
# 	1 : Range [NUMERICAL]
# 	1 : LargeAreaEmphasis [NUMERICAL]
# 	1 : InterquartileRange [NUMERICAL]
# 	1 : GrayLevelVariance.1 [NUMERICAL]
# 	1 : Contrast [NUMERICAL]
# 	1 : ClusterTendency [NUMERICAL]
# 	1 : ClusterProminence [NUMERICAL]
#
# Attribute in nodes with depth <= 3:
# 	174 : LongRunHighGrayLevelEmphasis [NUMERICAL]
# 	160 : GrayLevelNonUniformity.2 [NUMERICAL]
# 	151 : LargeDependenceHighGrayLevelEmphasis [NUMERICAL]
# 	130 : Mean [NUMERICAL]
# 	130 : Coarseness [NUMERICAL]
# 	120 : Median [NUMERICAL]
# 	118 : Skewness [NUMERICAL]
# 	113 : SumAverage [NUMERICAL]
# 	109 : Autocorrelation [NUMERICAL]
# 	108 : JointAverage [NUMERICAL]
# 	96 : Busyness [NUMERICAL]
# 	87 : HighGrayLevelEmphasis [NUMERICAL]
# 	85 : Energy [NUMERICAL]
# 	84 : DependenceEntropy [NUMERICAL]
# 	81 : 90Percentile [NUMERICAL]
# 	75 : ShortRunHighGrayLevelEmphasis [NUMERICAL]
# 	75 : LargeAreaHighGrayLevelEmphasis [NUMERICAL]
# 	72 : TotalEnergy [NUMERICAL]
# 	70 : Maximum [NUMERICAL]
# 	70 : ClusterShade [NUMERICAL]
# 	67 : Idn [NUMERICAL]
# 	60 : ShortRunLowGrayLevelEmphasis [NUMERICAL]
# 	60 : HighGrayLevelZoneEmphasis [NUMERICAL]
# 	57 : Imc1 [NUMERICAL]
# 	56 : RootMeanSquared [NUMERICAL]
# 	53 : HighGrayLevelRunEmphasis [NUMERICAL]
# 	51 : Idmn [NUMERICAL]
# 	50 : InverseVariance [NUMERICAL]
# 	49 : LowGrayLevelEmphasis [NUMERICAL]
# 	49 : LongRunLowGrayLevelEmphasis [NUMERICAL]
# 	44 : SmallDependenceLowGrayLevelEmphasis [NUMERICAL]
# 	44 : Correlation [NUMERICAL]
# 	41 : SmallAreaHighGrayLevelEmphasis [NUMERICAL]
# 	40 : GrayLevelNonUniformity [NUMERICAL]
# 	39 : LowGrayLevelRunEmphasis [NUMERICAL]
# 	38 : LowGrayLevelZoneEmphasis [NUMERICAL]
# 	36 : LargeAreaLowGrayLevelEmphasis [NUMERICAL]
# 	35 : LargeDependenceLowGrayLevelEmphasis [NUMERICAL]
# 	33 : Kurtosis [NUMERICAL]
# 	33 : Imc2 [NUMERICAL]
# 	32 : MCC [NUMERICAL]
# 	31 : SmallDependenceHighGrayLevelEmphasis [NUMERICAL]
# 	30 : Strength [NUMERICAL]
# 	27 : SumEntropy [NUMERICAL]
# 	26 : Uniformity [NUMERICAL]
# 	26 : SmallDependenceEmphasis [NUMERICAL]
# 	26 : SizeZoneNonUniformity [NUMERICAL]
# 	25 : JointEnergy [NUMERICAL]
# 	25 : GrayLevelVariance.2 [NUMERICAL]
# 	25 : DependenceNonUniformity [NUMERICAL]
# 	25 : 10Percentile [NUMERICAL]
# 	24 : LargeDependenceEmphasis [NUMERICAL]
# 	24 : GrayLevelNonUniformityNormalized [NUMERICAL]
# 	24 : DependenceVariance [NUMERICAL]
# 	24 : DependenceNonUniformityNormalized [NUMERICAL]
# 	23 : RunVariance [NUMERICAL]
# 	23 : GrayLevelNonUniformity.1 [NUMERICAL]
# 	23 : DifferenceVariance [NUMERICAL]
# 	22 : LongRunEmphasis [NUMERICAL]
# 	21 : Minimum [NUMERICAL]
# 	21 : GrayLevelNonUniformityNormalized.1 [NUMERICAL]
# 	21 : Contrast [NUMERICAL]
# 	20 : RunEntropy [NUMERICAL]
# 	20 : DifferenceAverage [NUMERICAL]
# 	18 : SmallAreaLowGrayLevelEmphasis [NUMERICAL]
# 	18 : RunPercentage [NUMERICAL]
# 	18 : Entropy [NUMERICAL]
# 	17 : ZonePercentage [NUMERICAL]
# 	17 : Range [NUMERICAL]
# 	17 : Id [NUMERICAL]
# 	16 : ZoneEntropy [NUMERICAL]
# 	16 : InterquartileRange [NUMERICAL]
# 	16 : DifferenceEntropy [NUMERICAL]
# 	16 : Complexity [NUMERICAL]
# 	15 : RunLengthNonUniformity [NUMERICAL]
# 	15 : MaximumProbability [NUMERICAL]
# 	14 : ShortRunEmphasis [NUMERICAL]
# 	13 : ZoneVariance [NUMERICAL]
# 	13 : SmallAreaEmphasis [NUMERICAL]
# 	13 : RunLengthNonUniformityNormalized [NUMERICAL]
# 	12 : Idm [NUMERICAL]
# 	12 : GrayLevelVariance [NUMERICAL]
# 	12 : Contrast.1 [NUMERICAL]
# 	11 : SizeZoneNonUniformityNormalized [NUMERICAL]
# 	10 : ClusterTendency [NUMERICAL]
# 	10 : ClusterProminence [NUMERICAL]
# 	9 : RobustMeanAbsoluteDeviation [NUMERICAL]
# 	9 : LargeAreaEmphasis [NUMERICAL]
# 	9 : JointEntropy [NUMERICAL]
# 	9 : GrayLevelVariance.1 [NUMERICAL]
# 	8 : MeanAbsoluteDeviation [NUMERICAL]
# 	7 : SumSquares [NUMERICAL]
# 	6 : Variance [NUMERICAL]
#
# Attribute in nodes with depth <= 5:
# 	317 : GrayLevelNonUniformity.2 [NUMERICAL]
# 	312 : Skewness [NUMERICAL]
# 	312 : Idn [NUMERICAL]
# 	279 : LargeDependenceHighGrayLevelEmphasis [NUMERICAL]
# 	279 : Coarseness [NUMERICAL]
# 	261 : LongRunHighGrayLevelEmphasis [NUMERICAL]
# 	257 : Idmn [NUMERICAL]
# 	250 : Busyness [NUMERICAL]
# 	240 : Median [NUMERICAL]
# 	217 : Maximum [NUMERICAL]
# 	214 : ClusterShade [NUMERICAL]
# 	205 : DependenceEntropy [NUMERICAL]
# 	197 : 90Percentile [NUMERICAL]
# 	190 : Mean [NUMERICAL]
# 	184 : SumAverage [NUMERICAL]
# 	177 : LargeAreaHighGrayLevelEmphasis [NUMERICAL]
# 	176 : Imc1 [NUMERICAL]
# 	175 : Autocorrelation [NUMERICAL]
# 	167 : JointAverage [NUMERICAL]
# 	154 : Correlation [NUMERICAL]
# 	151 : HighGrayLevelEmphasis [NUMERICAL]
# 	144 : HighGrayLevelZoneEmphasis [NUMERICAL]
# 	142 : Energy [NUMERICAL]
# 	135 : Imc2 [NUMERICAL]
# 	129 : ShortRunHighGrayLevelEmphasis [NUMERICAL]
# 	127 : TotalEnergy [NUMERICAL]
# 	125 : Kurtosis [NUMERICAL]
# 	123 : SmallAreaHighGrayLevelEmphasis [NUMERICAL]
# 	123 : ShortRunLowGrayLevelEmphasis [NUMERICAL]
# 	122 : LowGrayLevelZoneEmphasis [NUMERICAL]
# 	120 : MCC [NUMERICAL]
# 	118 : LowGrayLevelEmphasis [NUMERICAL]
# 	113 : SumEntropy [NUMERICAL]
# 	113 : SmallDependenceLowGrayLevelEmphasis [NUMERICAL]
# 	113 : LongRunLowGrayLevelEmphasis [NUMERICAL]
# 	112 : LowGrayLevelRunEmphasis [NUMERICAL]
# 	110 : RootMeanSquared [NUMERICAL]
# 	109 : SmallDependenceHighGrayLevelEmphasis [NUMERICAL]
# 	109 : InverseVariance [NUMERICAL]
# 	103 : LargeDependenceLowGrayLevelEmphasis [NUMERICAL]
# 	102 : GrayLevelNonUniformityNormalized [NUMERICAL]
# 	101 : Contrast.1 [NUMERICAL]
# 	96 : Strength [NUMERICAL]
# 	94 : HighGrayLevelRunEmphasis [NUMERICAL]
# 	93 : LargeAreaLowGrayLevelEmphasis [NUMERICAL]
# 	93 : GrayLevelNonUniformity [NUMERICAL]
# 	90 : SizeZoneNonUniformity [NUMERICAL]
# 	87 : Range [NUMERICAL]
# 	85 : DifferenceVariance [NUMERICAL]
# 	83 : SmallDependenceEmphasis [NUMERICAL]
# 	83 : GrayLevelNonUniformity.1 [NUMERICAL]
# 	83 : 10Percentile [NUMERICAL]
# 	82 : SmallAreaLowGrayLevelEmphasis [NUMERICAL]
# 	82 : Minimum [NUMERICAL]
# 	82 : DependenceNonUniformityNormalized [NUMERICAL]
# 	81 : Uniformity [NUMERICAL]
# 	81 : LargeDependenceEmphasis [NUMERICAL]
# 	81 : GrayLevelVariance.2 [NUMERICAL]
# 	79 : RunVariance [NUMERICAL]
# 	77 : DependenceVariance [NUMERICAL]
# 	77 : DependenceNonUniformity [NUMERICAL]
# 	76 : Contrast [NUMERICAL]
# 	75 : DifferenceAverage [NUMERICAL]
# 	72 : Complexity [NUMERICAL]
# 	71 : ZoneEntropy [NUMERICAL]
# 	71 : Entropy [NUMERICAL]
# 	71 : DifferenceEntropy [NUMERICAL]
# 	69 : SizeZoneNonUniformityNormalized [NUMERICAL]
# 	67 : JointEnergy [NUMERICAL]
# 	66 : ZonePercentage [NUMERICAL]
# 	65 : SmallAreaEmphasis [NUMERICAL]
# 	64 : RunEntropy [NUMERICAL]
# 	64 : GrayLevelNonUniformityNormalized.1 [NUMERICAL]
# 	63 : Idm [NUMERICAL]
# 	62 : MaximumProbability [NUMERICAL]
# 	61 : LongRunEmphasis [NUMERICAL]
# 	59 : InterquartileRange [NUMERICAL]
# 	58 : RunPercentage [NUMERICAL]
# 	58 : ClusterProminence [NUMERICAL]
# 	56 : Id [NUMERICAL]
# 	53 : RobustMeanAbsoluteDeviation [NUMERICAL]
# 	52 : RunLengthNonUniformity [NUMERICAL]
# 	50 : GrayLevelVariance [NUMERICAL]
# 	49 : ShortRunEmphasis [NUMERICAL]
# 	49 : RunLengthNonUniformityNormalized [NUMERICAL]
# 	48 : ZoneVariance [NUMERICAL]
# 	48 : GrayLevelVariance.1 [NUMERICAL]
# 	47 : ClusterTendency [NUMERICAL]
# 	43 : MeanAbsoluteDeviation [NUMERICAL]
# 	38 : JointEntropy [NUMERICAL]
# 	37 : LargeAreaEmphasis [NUMERICAL]
# 	34 : Variance [NUMERICAL]
# 	32 : SumSquares [NUMERICAL]
#
# Condition type in nodes:
# 	29923 : HigherCondition
# Condition type in nodes with depth <= 0:
# 	300 : HigherCondition
# Condition type in nodes with depth <= 1:
# 	900 : HigherCondition
# Condition type in nodes with depth <= 2:
# 	2071 : HigherCondition
# Condition type in nodes with depth <= 3:
# 	4007 : HigherCondition
# Condition type in nodes with depth <= 5:
# 	10644 : HigherCondition
# Node format: NOT_SET
#
# Training OOB:
# 	trees: 1, Out-of-bag evaluation: accuracy:0.847009 logloss:5.51436
# 	trees: 11, Out-of-bag evaluation: accuracy:0.845516 logloss:2.28913
# 	trees: 21, Out-of-bag evaluation: accuracy:0.858845 logloss:1.34225
# 	trees: 31, Out-of-bag evaluation: accuracy:0.87014 logloss:0.919567
# 	trees: 41, Out-of-bag evaluation: accuracy:0.870351 logloss:0.820334
# 	trees: 51, Out-of-bag evaluation: accuracy:0.870421 logloss:0.649661
# 	trees: 61, Out-of-bag evaluation: accuracy:0.86919 logloss:0.61475
# 	trees: 71, Out-of-bag evaluation: accuracy:0.871301 logloss:0.545875
# 	trees: 81, Out-of-bag evaluation: accuracy:0.870631 logloss:0.510861
# 	trees: 91, Out-of-bag evaluation: accuracy:0.869471 logloss:0.51007
# 	trees: 101, Out-of-bag evaluation: accuracy:0.86662 logloss:0.508983
# 	trees: 111, Out-of-bag evaluation: accuracy:0.864509 logloss:0.50886
# 	trees: 121, Out-of-bag evaluation: accuracy:0.86662 logloss:0.47384
# 	trees: 131, Out-of-bag evaluation: accuracy:0.86669 logloss:0.473528
# 	trees: 141, Out-of-bag evaluation: accuracy:0.868731 logloss:0.475385
# 	trees: 151, Out-of-bag evaluation: accuracy:0.870912 logloss:0.440646
# 	trees: 161, Out-of-bag evaluation: accuracy:0.870772 logloss:0.440021
# 	trees: 171, Out-of-bag evaluation: accuracy:0.86859 logloss:0.437652
# 	trees: 181, Out-of-bag evaluation: accuracy:0.871722 logloss:0.436417
# 	trees: 191, Out-of-bag evaluation: accuracy:0.870701 logloss:0.436207
# 	trees: 201, Out-of-bag evaluation: accuracy:0.872602 logloss:0.403586
# 	trees: 211, Out-of-bag evaluation: accuracy:0.871722 logloss:0.403279
# 	trees: 221, Out-of-bag evaluation: accuracy:0.872532 logloss:0.40359
# 	trees: 231, Out-of-bag evaluation: accuracy:0.872672 logloss:0.403229
# 	trees: 241, Out-of-bag evaluation: accuracy:0.872602 logloss:0.402499
# 	trees: 251, Out-of-bag evaluation: accuracy:0.871722 logloss:0.403038
# 	trees: 261, Out-of-bag evaluation: accuracy:0.874502 logloss:0.402964
# 	trees: 271, Out-of-bag evaluation: accuracy:0.874573 logloss:0.402303
# 	trees: 281, Out-of-bag evaluation: accuracy:0.876543 logloss:0.337448
# 	trees: 291, Out-of-bag evaluation: accuracy:0.877564 logloss:0.337949
# 	trees: 300, Out-of-bag evaluation: accuracy:0.877634 logloss:0.337551

# %%
# Model features
model.make_inspector().features()
# Out:
# ["10Percentile" (1; #0),
#  "90Percentile" (1; #1),
#  "Autocorrelation" (1; #2),
#  "Busyness" (1; #3),
#  "ClusterProminence" (1; #4),
#  "ClusterShade" (1; #5),
#  "ClusterTendency" (1; #6),
#  "Coarseness" (1; #7),
#  "Complexity" (1; #8),
#  "Contrast" (1; #9),
#  "Contrast.1" (1; #10),
#  "Correlation" (1; #11),
#  "DependenceEntropy" (1; #12),
#  "DependenceNonUniformity" (1; #13),
#  "DependenceNonUniformityNormalized" (1; #14),
#  "DependenceVariance" (1; #15),
#  "DifferenceAverage" (1; #16),
#  "DifferenceEntropy" (1; #17),
#  "DifferenceVariance" (1; #18),
#  "Energy" (1; #19),
#  "Entropy" (1; #20),
#  "GrayLevelNonUniformity" (1; #21),
#  "GrayLevelNonUniformity.1" (1; #22),
#  "GrayLevelNonUniformity.2" (1; #23),
#  "GrayLevelNonUniformityNormalized" (1; #24),
#  "GrayLevelNonUniformityNormalized.1" (1; #25),
#  "GrayLevelVariance" (1; #26),
#  "GrayLevelVariance.1" (1; #27),
#  "GrayLevelVariance.2" (1; #28),
#  "HighGrayLevelEmphasis" (1; #29),
#  "HighGrayLevelRunEmphasis" (1; #30),
#  "HighGrayLevelZoneEmphasis" (1; #31),
#  "Id" (1; #32),
#  "Idm" (1; #33),
#  "Idmn" (1; #34),
#  "Idn" (1; #35),
#  "Imc1" (1; #36),
#  "Imc2" (1; #37),
#  "InterquartileRange" (1; #38),
#  "InverseVariance" (1; #39),
#  "JointAverage" (1; #40),
#  "JointEnergy" (1; #41),
#  "JointEntropy" (1; #42),
#  "Kurtosis" (1; #43),
#  "LargeAreaEmphasis" (1; #44),
#  "LargeAreaHighGrayLevelEmphasis" (1; #45),
#  "LargeAreaLowGrayLevelEmphasis" (1; #46),
#  "LargeDependenceEmphasis" (1; #47),
#  "LargeDependenceHighGrayLevelEmphasis" (1; #48),
#  "LargeDependenceLowGrayLevelEmphasis" (1; #49),
#  "LongRunEmphasis" (1; #50),
#  "LongRunHighGrayLevelEmphasis" (1; #51),
#  "LongRunLowGrayLevelEmphasis" (1; #52),
#  "LowGrayLevelEmphasis" (1; #53),
#  "LowGrayLevelRunEmphasis" (1; #54),
#  "LowGrayLevelZoneEmphasis" (1; #55),
#  "MCC" (1; #56),
#  "Maximum" (1; #57),
#  "MaximumProbability" (1; #58),
#  "Mean" (1; #59),
#  "MeanAbsoluteDeviation" (1; #60),
#  "Median" (1; #61),
#  "Minimum" (1; #62),
#  "Range" (1; #63),
#  "RobustMeanAbsoluteDeviation" (1; #64),
#  "RootMeanSquared" (1; #65),
#  "RunEntropy" (1; #66),
#  "RunLengthNonUniformity" (1; #67),
#  "RunLengthNonUniformityNormalized" (1; #68),
#  "RunPercentage" (1; #69),
#  "RunVariance" (1; #70),
#  "ShortRunEmphasis" (1; #71),
#  "ShortRunHighGrayLevelEmphasis" (1; #72),
#  "ShortRunLowGrayLevelEmphasis" (1; #73),
#  "SizeZoneNonUniformity" (1; #74),
#  "SizeZoneNonUniformityNormalized" (1; #75),
#  "Skewness" (1; #76),
#  "SmallAreaEmphasis" (1; #77),
#  "SmallAreaHighGrayLevelEmphasis" (1; #78),
#  "SmallAreaLowGrayLevelEmphasis" (1; #79),
#  "SmallDependenceEmphasis" (1; #80),
#  "SmallDependenceHighGrayLevelEmphasis" (1; #81),
#  "SmallDependenceLowGrayLevelEmphasis" (1; #82),
#  "Strength" (1; #83),
#  "SumAverage" (1; #84),
#  "SumEntropy" (1; #85),
#  "SumSquares" (1; #86),
#  "TotalEnergy" (1; #87),
#  "Uniformity" (1; #88),
#  "Variance" (1; #89),
#  "ZoneEntropy" (1; #90),
#  "ZonePercentage" (1; #91),
#  "ZoneVariance" (1; #92)]

# %%
# Feature importance
model.make_inspector().variable_importances()
# Out:
# {'INV_MEAN_MIN_DEPTH': [("LongRunHighGrayLevelEmphasis" (1; #51),
#    0.1332531815799405),
#   ("GrayLevelNonUniformity.2" (1; #23), 0.12688592884698846),
#   ("LargeDependenceHighGrayLevelEmphasis" (1; #48), 0.1256591591662688),
#   ("Mean" (1; #59), 0.12255739896391418),
#   ("Coarseness" (1; #7), 0.12151435645158458),
#   ("90Percentile" (1; #1), 0.12070346078313023),
#   ("Median" (1; #61), 0.11985904243637806),
#   ("HighGrayLevelZoneEmphasis" (1; #31), 0.11958629842855434),
#   ("Busyness" (1; #3), 0.11938966763283708),
#   ("HighGrayLevelEmphasis" (1; #29), 0.11874852781484482),
#   ("JointAverage" (1; #40), 0.11802487996836344),
#   ("Autocorrelation" (1; #2), 0.11760048448305548),
#   ("SumAverage" (1; #84), 0.11739175971984009),
#   ("LargeAreaHighGrayLevelEmphasis" (1; #45), 0.11697070985120417),
#   ("Energy" (1; #19), 0.1168828178424311),
#   ("TotalEnergy" (1; #87), 0.1166492734107691),
#   ("Maximum" (1; #57), 0.1156206777482429),
#   ("Idn" (1; #35), 0.11500312422990219),
#   ("RootMeanSquared" (1; #65), 0.1146401048098256),
#   ("Idmn" (1; #34), 0.11368328435737364),
#   ("DependenceEntropy" (1; #12), 0.11352097034589871),
#   ("InverseVariance" (1; #39), 0.11323997294611546),
#   ("ShortRunHighGrayLevelEmphasis" (1; #72), 0.11303998044515076),
#   ("Skewness" (1; #76), 0.1127877752230807),
#   ("SmallDependenceLowGrayLevelEmphasis" (1; #82), 0.11249343692446566),
#   ("SmallAreaHighGrayLevelEmphasis" (1; #78), 0.11242751759162845),
#   ("Imc1" (1; #36), 0.11171559818008035),
#   ("ShortRunLowGrayLevelEmphasis" (1; #73), 0.11125476490211908),
#   ("LowGrayLevelRunEmphasis" (1; #54), 0.11120483896718633),
#   ("LowGrayLevelEmphasis" (1; #53), 0.11096487705466111),
#   ("LongRunLowGrayLevelEmphasis" (1; #52), 0.1105379356513571),
#   ("LargeDependenceLowGrayLevelEmphasis" (1; #49), 0.11048470985237485),
#   ("HighGrayLevelRunEmphasis" (1; #30), 0.11003206261304688),
#   ("ClusterShade" (1; #5), 0.10998942244518144),
#   ("MCC" (1; #56), 0.1095615045046497),
#   ("Correlation" (1; #11), 0.1095277355842697),
#   ("LowGrayLevelZoneEmphasis" (1; #55), 0.10949780717296358),
#   ("Imc2" (1; #37), 0.10941594377840975),
#   ("SmallDependenceHighGrayLevelEmphasis" (1; #81), 0.10923794810062243),
#   ("10Percentile" (1; #0), 0.10917688669455507),
#   ("Minimum" (1; #62), 0.10899703950164967),
#   ("DependenceNonUniformity" (1; #13), 0.10894358900673896),
#   ("DependenceNonUniformityNormalized" (1; #14), 0.10873852930266106),
#   ("SizeZoneNonUniformity" (1; #74), 0.10873291278665331),
#   ("SmallAreaLowGrayLevelEmphasis" (1; #79), 0.10866070800767194),
#   ("DependenceVariance" (1; #15), 0.10864380007504168),
#   ("SmallDependenceEmphasis" (1; #80), 0.1086166396351361),
#   ("GrayLevelNonUniformity" (1; #21), 0.10834559837484552),
#   ("RunVariance" (1; #70), 0.10831728034618146),
#   ("Strength" (1; #83), 0.10825095405416289),
#   ("LargeAreaLowGrayLevelEmphasis" (1; #46), 0.10822290835645738),
#   ("ZonePercentage" (1; #91), 0.1080422508988289),
#   ("SumEntropy" (1; #85), 0.1079728781628793),
#   ("Kurtosis" (1; #43), 0.10794177772606244),
#   ("LargeDependenceEmphasis" (1; #47), 0.10780702021795811),
#   ("LongRunEmphasis" (1; #50), 0.10770791690921043),
#   ("Contrast.1" (1; #10), 0.10765795694076684),
#   ("Idm" (1; #33), 0.10764459909446679),
#   ("GrayLevelVariance.2" (1; #28), 0.1076283899493298),
#   ("Uniformity" (1; #88), 0.10753477607063366),
#   ("Range" (1; #63), 0.10747124479981442),
#   ("GrayLevelNonUniformity.1" (1; #22), 0.10744930434370052),
#   ("DifferenceAverage" (1; #16), 0.10743911996873597),
#   ("Id" (1; #32), 0.10742740552590416),
#   ("DifferenceVariance" (1; #18), 0.10742209829177943),
#   ("GrayLevelNonUniformityNormalized" (1; #24), 0.10735709448527186),
#   ("SmallAreaEmphasis" (1; #77), 0.10731067417527573),
#   ("GrayLevelNonUniformityNormalized.1" (1; #25), 0.10731010722398553),
#   ("Contrast" (1; #9), 0.10726063159183753),
#   ("DifferenceEntropy" (1; #17), 0.10721758639338828),
#   ("MaximumProbability" (1; #58), 0.10717601089083659),
#   ("RunEntropy" (1; #66), 0.1071207473029016),
#   ("Entropy" (1; #20), 0.10706703228451248),
#   ("ZoneEntropy" (1; #90), 0.10699739662425914),
#   ("RunPercentage" (1; #69), 0.10699303638773018),
#   ("SizeZoneNonUniformityNormalized" (1; #75), 0.10698422657046959),
#   ("JointEnergy" (1; #41), 0.1069748097675059),
#   ("ShortRunEmphasis" (1; #71), 0.10695330064281963),
#   ("ClusterTendency" (1; #6), 0.10691553651199474),
#   ("ZoneVariance" (1; #92), 0.1069151989942251),
#   ("RunLengthNonUniformity" (1; #67), 0.1068249420792882),
#   ("Complexity" (1; #8), 0.10681596546056199),
#   ("RunLengthNonUniformityNormalized" (1; #68), 0.10677879297841275),
#   ("ClusterProminence" (1; #4), 0.10677602081302036),
#   ("InterquartileRange" (1; #38), 0.10667629680222766),
#   ("RobustMeanAbsoluteDeviation" (1; #64), 0.10655341958003571),
#   ("GrayLevelVariance" (1; #26), 0.10649330253861941),
#   ("GrayLevelVariance.1" (1; #27), 0.10634564038759899),
#   ("MeanAbsoluteDeviation" (1; #60), 0.10631347199654863),
#   ("Variance" (1; #89), 0.10629798724684622),
#   ("SumSquares" (1; #86), 0.10624341056125111),
#   ("JointEntropy" (1; #42), 0.10621321717737282),
#   ("LargeAreaEmphasis" (1; #44), 0.10598291568107256)],
#  'SUM_SCORE': [("LongRunHighGrayLevelEmphasis" (1; #51), 100774.81350219094),
#   ("90Percentile" (1; #1), 68462.59262332827),
#   ("HighGrayLevelZoneEmphasis" (1; #31), 68075.15936517098),
#   ("Mean" (1; #59), 67505.24486614268),
#   ("HighGrayLevelEmphasis" (1; #29), 59061.92333938506),
#   ("TotalEnergy" (1; #87), 51660.99426461792),
#   ("LargeDependenceHighGrayLevelEmphasis" (1; #48), 50405.274654704044),
#   ("SumAverage" (1; #84), 47138.55855199616),
#   ("Energy" (1; #19), 46787.74740763584),
#   ("Autocorrelation" (1; #2), 46720.988779906686),
#   ("JointAverage" (1; #40), 46519.00180442767),
#   ("GrayLevelNonUniformity.2" (1; #23), 41193.75735716203),
#   ("RootMeanSquared" (1; #65), 38447.0290016125),
#   ("Idn" (1; #35), 34891.68424085481),
#   ("Median" (1; #61), 33928.30515545482),
#   ("Maximum" (1; #57), 33817.541144758754),
#   ("Coarseness" (1; #7), 31294.280533457193),
#   ("SmallAreaHighGrayLevelEmphasis" (1; #78), 30204.43098800518),
#   ("Busyness" (1; #3), 29638.19815107538),
#   ("ShortRunHighGrayLevelEmphasis" (1; #72), 29158.29855271102),
#   ("Idmn" (1; #34), 28042.243875021315),
#   ("LargeAreaHighGrayLevelEmphasis" (1; #45), 24136.290029937423),
#   ("DependenceEntropy" (1; #12), 17676.01521673585),
#   ("Skewness" (1; #76), 17440.09254282914),
#   ("ShortRunLowGrayLevelEmphasis" (1; #73), 16858.526890190376),
#   ("HighGrayLevelRunEmphasis" (1; #30), 15875.172083988604),
#   ("LowGrayLevelRunEmphasis" (1; #54), 15323.161986569743),
#   ("LowGrayLevelZoneEmphasis" (1; #55), 14491.018065823606),
#   ("InverseVariance" (1; #39), 14016.77762499445),
#   ("Imc1" (1; #36), 13188.016355448317),
#   ("SmallDependenceLowGrayLevelEmphasis" (1; #82), 12646.458371668587),
#   ("LowGrayLevelEmphasis" (1; #53), 12185.155337175307),
#   ("LongRunLowGrayLevelEmphasis" (1; #52), 11630.741301630776),
#   ("LargeDependenceLowGrayLevelEmphasis" (1; #49), 11598.917740886294),
#   ("ClusterShade" (1; #5), 11054.177511494903),
#   ("Correlation" (1; #11), 10243.826012850106),
#   ("Minimum" (1; #62), 9894.942103476204),
#   ("Imc2" (1; #37), 9875.84729539897),
#   ("SmallDependenceHighGrayLevelEmphasis" (1; #81), 9543.99262721287),
#   ("SmallAreaLowGrayLevelEmphasis" (1; #79), 9523.30321720206),
#   ("MCC" (1; #56), 9259.068917345592),
#   ("10Percentile" (1; #0), 9140.426352146667),
#   ("SumEntropy" (1; #85), 8570.360512117444),
#   ("SizeZoneNonUniformity" (1; #74), 8308.451476668675),
#   ("Contrast.1" (1; #10), 8061.665586958681),
#   ("DependenceVariance" (1; #15), 7731.24423029718),
#   ("DependenceNonUniformity" (1; #13), 7474.326014660838),
#   ("DependenceNonUniformityNormalized" (1; #14), 7450.407225362594),
#   ("SmallDependenceEmphasis" (1; #80), 7399.218926494422),
#   ("GrayLevelNonUniformity" (1; #21), 7293.406949862451),
#   ("Strength" (1; #83), 7251.534102595194),
#   ("LargeAreaLowGrayLevelEmphasis" (1; #46), 7131.3823959263855),
#   ("ZonePercentage" (1; #91), 6476.537021750086),
#   ("RunVariance" (1; #70), 6327.356836506255),
#   ("Contrast" (1; #9), 6176.161275718141),
#   ("DifferenceAverage" (1; #16), 6094.97992891941),
#   ("Kurtosis" (1; #43), 6018.4751915663355),
#   ("DifferenceEntropy" (1; #17), 5766.549353439722),
#   ("GrayLevelNonUniformityNormalized.1" (1; #25), 5749.367349088661),
#   ("Idm" (1; #33), 5698.404648114507),
#   ("DifferenceVariance" (1; #18), 5624.952741180945),
#   ("Uniformity" (1; #88), 5596.912439424435),
#   ("SizeZoneNonUniformityNormalized" (1; #75), 5588.685069242475),
#   ("GrayLevelVariance.2" (1; #28), 5583.863530404154),
#   ("GrayLevelNonUniformity.1" (1; #22), 5580.380118581217),
#   ("SmallAreaEmphasis" (1; #77), 5553.736895359116),
#   ("RunEntropy" (1; #66), 5484.749924288516),
#   ("LargeDependenceEmphasis" (1; #47), 5467.206698413366),
#   ("ZoneEntropy" (1; #90), 5444.891329562266),
#   ("Range" (1; #63), 5408.406059037359),
#   ("LongRunEmphasis" (1; #50), 5289.438928819677),
#   ("Entropy" (1; #20), 5257.849713438817),
#   ("GrayLevelNonUniformityNormalized" (1; #24), 5203.077901114751),
#   ("Id" (1; #32), 5059.880967089408),
#   ("MaximumProbability" (1; #58), 4906.654011907777),
#   ("JointEnergy" (1; #41), 4382.827306009149),
#   ("ClusterTendency" (1; #6), 4367.77035856977),
#   ("RunPercentage" (1; #69), 4330.059307362524),
#   ("ShortRunEmphasis" (1; #71), 4299.040971386975),
#   ("ZoneVariance" (1; #92), 4186.738741263528),
#   ("RunLengthNonUniformity" (1; #67), 4078.1777820077486),
#   ("Complexity" (1; #8), 3888.27103890459),
#   ("GrayLevelVariance.1" (1; #27), 3627.7418696222476),
#   ("InterquartileRange" (1; #38), 3599.727370676355),
#   ("GrayLevelVariance" (1; #26), 3561.972431211538),
#   ("ClusterProminence" (1; #4), 3483.671929202468),
#   ("RunLengthNonUniformityNormalized" (1; #68), 3404.1215945922654),
#   ("RobustMeanAbsoluteDeviation" (1; #64), 3390.0459010014583),
#   ("Variance" (1; #89), 3375.0408396052167),
#   ("MeanAbsoluteDeviation" (1; #60), 3334.542807661903),
#   ("JointEntropy" (1; #42), 3235.628536182284),
#   ("SumSquares" (1; #86), 2645.46670151708),
#   ("LargeAreaEmphasis" (1; #44), 2307.988244748168)],
#  'NUM_AS_ROOT': [("LongRunHighGrayLevelEmphasis" (1; #51), 31.0),
#   ("HighGrayLevelZoneEmphasis" (1; #31), 27.0),
#   ("90Percentile" (1; #1), 26.0),
#   ("Mean" (1; #59), 25.0),
#   ("HighGrayLevelEmphasis" (1; #29), 23.0),
#   ("TotalEnergy" (1; #87), 20.0),
#   ("Autocorrelation" (1; #2), 16.0),
#   ("Energy" (1; #19), 16.0),
#   ("JointAverage" (1; #40), 16.0),
#   ("SumAverage" (1; #84), 16.0),
#   ("RootMeanSquared" (1; #65), 13.0),
#   ("SmallAreaHighGrayLevelEmphasis" (1; #78), 10.0),
#   ("ShortRunHighGrayLevelEmphasis" (1; #72), 9.0),
#   ("Maximum" (1; #57), 8.0),
#   ("Median" (1; #61), 6.0),
#   ("HighGrayLevelRunEmphasis" (1; #30), 4.0),
#   ("LowGrayLevelZoneEmphasis" (1; #55), 4.0),
#   ("Minimum" (1; #62), 4.0),
#   ("ShortRunLowGrayLevelEmphasis" (1; #73), 4.0),
#   ("LowGrayLevelRunEmphasis" (1; #54), 3.0),
#   ("Busyness" (1; #3), 2.0),
#   ("LowGrayLevelEmphasis" (1; #53), 2.0),
#   ("SmallAreaLowGrayLevelEmphasis" (1; #79), 2.0),
#   ("10Percentile" (1; #0), 1.0),
#   ("Coarseness" (1; #7), 1.0),
#   ("DependenceEntropy" (1; #12), 1.0),
#   ("GrayLevelNonUniformity" (1; #21), 1.0),
#   ("GrayLevelNonUniformityNormalized" (1; #24), 1.0),
#   ("Imc1" (1; #36), 1.0),
#   ("LargeDependenceHighGrayLevelEmphasis" (1; #48), 1.0),
#   ("LargeDependenceLowGrayLevelEmphasis" (1; #49), 1.0),
#   ("LongRunLowGrayLevelEmphasis" (1; #52), 1.0),
#   ("MCC" (1; #56), 1.0),
#   ("SmallDependenceHighGrayLevelEmphasis" (1; #81), 1.0),
#   ("SmallDependenceLowGrayLevelEmphasis" (1; #82), 1.0),
#   ("Uniformity" (1; #88), 1.0)],
#  'NUM_NODES': [("Idn" (1; #35), 1045.0),
#   ("Idmn" (1; #34), 885.0),
#   ("Skewness" (1; #76), 742.0),
#   ("GrayLevelNonUniformity.2" (1; #23), 674.0),
#   ("LargeDependenceHighGrayLevelEmphasis" (1; #48), 646.0),
#   ("Coarseness" (1; #7), 613.0),
#   ("Busyness" (1; #3), 571.0),
#   ("ClusterShade" (1; #5), 550.0),
#   ("Maximum" (1; #57), 528.0),
#   ("Median" (1; #61), 521.0),
#   ("LongRunHighGrayLevelEmphasis" (1; #51), 498.0),
#   ("90Percentile" (1; #1), 430.0),
#   ("Correlation" (1; #11), 424.0),
#   ("DependenceEntropy" (1; #12), 421.0),
#   ("MCC" (1; #56), 393.0),
#   ("LargeAreaHighGrayLevelEmphasis" (1; #45), 390.0),
#   ("Imc1" (1; #36), 389.0),
#   ("Kurtosis" (1; #43), 381.0),
#   ("SumAverage" (1; #84), 376.0),
#   ("SmallAreaHighGrayLevelEmphasis" (1; #78), 372.0),
#   ("Contrast.1" (1; #10), 369.0),
#   ("Autocorrelation" (1; #2), 362.0),
#   ("Imc2" (1; #37), 359.0),
#   ("HighGrayLevelZoneEmphasis" (1; #31), 358.0),
#   ("Mean" (1; #59), 346.0),
#   ("SmallAreaLowGrayLevelEmphasis" (1; #79), 335.0),
#   ("JointAverage" (1; #40), 334.0),
#   ("LowGrayLevelZoneEmphasis" (1; #55), 333.0),
#   ("LargeDependenceLowGrayLevelEmphasis" (1; #49), 327.0),
#   ("SmallDependenceLowGrayLevelEmphasis" (1; #82), 326.0),
#   ("Strength" (1; #83), 321.0),
#   ("HighGrayLevelEmphasis" (1; #29), 314.0),
#   ("Contrast" (1; #9), 312.0),
#   ("LongRunLowGrayLevelEmphasis" (1; #52), 310.0),
#   ("Range" (1; #63), 309.0),
#   ("Minimum" (1; #62), 303.0),
#   ("SumEntropy" (1; #85), 301.0),
#   ("DifferenceVariance" (1; #18), 300.0),
#   ("GrayLevelVariance.2" (1; #28), 300.0),
#   ("SizeZoneNonUniformityNormalized" (1; #75), 300.0),
#   ("SmallDependenceHighGrayLevelEmphasis" (1; #81), 298.0),
#   ("DependenceVariance" (1; #15), 297.0),
#   ("Energy" (1; #19), 297.0),
#   ("ShortRunHighGrayLevelEmphasis" (1; #72), 290.0),
#   ("TotalEnergy" (1; #87), 289.0),
#   ("LargeAreaLowGrayLevelEmphasis" (1; #46), 288.0),
#   ("ShortRunLowGrayLevelEmphasis" (1; #73), 287.0),
#   ("LowGrayLevelRunEmphasis" (1; #54), 286.0),
#   ("InverseVariance" (1; #39), 282.0),
#   ("10Percentile" (1; #0), 281.0),
#   ("SmallAreaEmphasis" (1; #77), 276.0),
#   ("SizeZoneNonUniformity" (1; #74), 271.0),
#   ("LowGrayLevelEmphasis" (1; #53), 270.0),
#   ("DifferenceAverage" (1; #16), 268.0),
#   ("RootMeanSquared" (1; #65), 267.0),
#   ("HighGrayLevelRunEmphasis" (1; #30), 264.0),
#   ("ZoneEntropy" (1; #90), 263.0),
#   ("GrayLevelNonUniformityNormalized.1" (1; #25), 262.0),
#   ("SmallDependenceEmphasis" (1; #80), 261.0),
#   ("Complexity" (1; #8), 260.0),
#   ("DifferenceEntropy" (1; #17), 254.0),
#   ("GrayLevelNonUniformityNormalized" (1; #24), 254.0),
#   ("GrayLevelNonUniformity" (1; #21), 252.0),
#   ("GrayLevelNonUniformity.1" (1; #22), 252.0),
#   ("RunVariance" (1; #70), 250.0),
#   ("Uniformity" (1; #88), 245.0),
#   ("InterquartileRange" (1; #38), 240.0),
#   ("DependenceNonUniformityNormalized" (1; #14), 232.0),
#   ("MaximumProbability" (1; #58), 232.0),
#   ("DependenceNonUniformity" (1; #13), 225.0),
#   ("JointEnergy" (1; #41), 225.0),
#   ("ZonePercentage" (1; #91), 225.0),
#   ("Idm" (1; #33), 223.0),
#   ("LargeDependenceEmphasis" (1; #47), 223.0),
#   ("Id" (1; #32), 222.0),
#   ("RunEntropy" (1; #66), 219.0),
#   ("Entropy" (1; #20), 214.0),
#   ("RobustMeanAbsoluteDeviation" (1; #64), 211.0),
#   ("ClusterProminence" (1; #4), 209.0),
#   ("LongRunEmphasis" (1; #50), 209.0),
#   ("GrayLevelVariance" (1; #26), 202.0),
#   ("JointEntropy" (1; #42), 201.0),
#   ("ClusterTendency" (1; #6), 200.0),
#   ("ZoneVariance" (1; #92), 198.0),
#   ("GrayLevelVariance.1" (1; #27), 197.0),
#   ("MeanAbsoluteDeviation" (1; #60), 182.0),
#   ("RunLengthNonUniformityNormalized" (1; #68), 181.0),
#   ("RunLengthNonUniformity" (1; #67), 177.0),
#   ("ShortRunEmphasis" (1; #71), 177.0),
#   ("Variance" (1; #89), 174.0),
#   ("RunPercentage" (1; #69), 169.0),
#   ("SumSquares" (1; #86), 163.0),
#   ("LargeAreaEmphasis" (1; #44), 161.0)]}

# %%
# Model self evaluation
model.make_inspector().evaluation()
# Out:
# Evaluation(num_examples=7617, accuracy=0.877633776116085, loss=0.3375513826051613, rmse=None, ndcg=None, aucs=None, auuc=None, qini=None)

# %%
logs = model.make_inspector().training_logs()

plt.figure(figsize=(12, 4))
plt.subplot(1, 2, 1)
plt.plot([log.num_trees for log in logs], [log.evaluation.accuracy for log in logs])
plt.xlabel("Number of trees")
plt.ylabel("Accuracy (out-of-bag)")
plt.subplot(1, 2, 2)
plt.plot([log.num_trees for log in logs], [log.evaluation.loss for log in logs])
plt.xlabel("Number of trees")
plt.ylabel("Logloss (out-of-bag)")
plt.show()

# %% [markdown]
# Calculate the score of our hold-out validation dataset

# %%
predictions = model.predict(val_ds)
y_true      = validation_data["label"]

from sklearn.metrics import roc_auc_score
ROC_AUC = roc_auc_score(y_true, predictions)
print("The ROC AUC score is %.5f" % ROC_AUC )
# Out:
# 1/2 [==============>...............] - ETA: 0s
# 2/2 [==============================] - 0s 5ms/step
# The ROC AUC score is 0.99913

# %%
# Compute binary classification metrics with sklearn
import numpy as np
from sklearn.metrics import (
    accuracy_score,
    precision_score,
    recall_score,
    f1_score,
    roc_auc_score,
    average_precision_score,
    confusion_matrix,
    classification_report,
    matthews_corrcoef,
    log_loss,
    brier_score_loss,
)

# Get predictions (probabilities or class labels)
preds = model.predict(test_ds)
# If model outputs probabilities, convert to labels by threshold 0.5
if preds.ndim == 2:
    # For TFDF classification, preds may be class probabilities with shape (N, 2)
    if preds.shape[1] == 2:
        pos_probs = preds[:, 1]
    else:
        # If single-probability column (positive class)
        pos_probs = preds[:, -1]
    y_pred = (pos_probs >= 0.5).astype(int)
else:
    # Already class labels
    y_pred = preds.astype(int)
    pos_probs = None

# Ground truth labels (must be 0/1 integers)
y_true = test_data["label"].astype(int).to_numpy()

# Core metrics
metrics = {}
metrics["accuracy"] = accuracy_score(y_true, y_pred)
metrics["precision"] = precision_score(y_true, y_pred, zero_division=0)
metrics["recall"] = recall_score(y_true, y_pred, zero_division=0)
metrics["f1"] = f1_score(y_true, y_pred, zero_division=0)
metrics["mcc"] = matthews_corrcoef(y_true, y_pred)

# Probabilistic metrics (only if we have probabilities)
if pos_probs is not None:
    metrics["roc_auc"] = roc_auc_score(y_true, pos_probs)
    metrics["pr_auc"] = average_precision_score(y_true, pos_probs)
    metrics["log_loss"] = log_loss(y_true, pos_probs, labels=[0,1])
    metrics["brier_score"] = brier_score_loss(y_true, pos_probs)

# Confusion matrix and detailed report
cm = confusion_matrix(y_true, y_pred, labels=[0,1])
report = classification_report(y_true, y_pred, digits=4)

print("Sklearn binary metrics:")
for k, v in metrics.items():
    print(f"{k}: {v:.4f}")
print("\nConfusion matrix:\n", cm)
print("\nClassification report:\n", report)
# Out:
# 1/3 [=========>....................] - ETA: 0s
# 3/3 [==============================] - 0s 18ms/step
# Sklearn binary metrics:
# accuracy: 0.9671
# precision: 0.9176
# recall: 0.7357
# f1: 0.8166
# mcc: 0.8047
# roc_auc: 0.9813
# pr_auc: 0.8970
# log_loss: 0.0942
# brier_score: 0.0254
#
# Confusion matrix:
#  [[2041   15]
#  [  60  167]]
#
# Classification report:
#                precision    recall  f1-score   support
#
#            0     0.9714    0.9927    0.9820      2056
#            1     0.9176    0.7357    0.8166       227
#
#     accuracy                         0.9671      2283
#    macro avg     0.9445    0.8642    0.8993      2283
# weighted avg     0.9661    0.9671    0.9655      2283
