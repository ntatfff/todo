# %%
# Import packages and modules
import numpy  as np
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow_decision_forests as tfdf

from sklearn.model_selection import train_test_split
# Out:
# 2026-07-04 08:38:19.270474: I tensorflow/core/util/port.cc:113] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2026-07-04 08:38:19.310691: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2026-07-04 08:38:23.628530: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
# Check the version of TensorFlow Decision Forests
print("Found TensorFlow Decision Forests v" + tfdf.__version__)
# Out:
# Found TensorFlow Decision Forests v1.9.1

# %%
datasetPath = 'dataset/firstorder/kernel5-radius5/dataset.csv'

# %%
# Parameters
datasetPath = "dataset/gldm/kernel5-radius5/500.dataset.csv"

# %%
# train/validation/test = 70/10/20
dataset = pd.read_csv(datasetPath)

train_data, temp_data = train_test_split(dataset, test_size=0.3, random_state=42)
validation_data, test_data = train_test_split(temp_data, test_size=2/3, random_state=42)

# %%
from sklearn.utils.class_weight import compute_class_weight

# tinh class weight tren tap train
classes = np.array([0, 1])
weights = compute_class_weight(class_weight="balanced", classes=classes, y=train_data["label"])
class_weight = {0: weights[0], 1: weights[1]}

# gan sample_weight cho tung dong
train_data["sample_weight"] = train_data["label"].map(class_weight)
validation_data["sample_weight"] = validation_data["label"].map(class_weight)
test_data["sample_weight"] = test_data["label"].map(class_weight)

# Convert the dataset into a TensorFlow dataset.
train_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    train_data, label="label", weight="sample_weight"
)         
val_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    validation_data, label="label", weight="sample_weight"
)
test_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    test_data, label="label", weight="sample_weight"
)
# Out:
# 2026-07-04 08:38:37.770925: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:984] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2026-07-04 08:38:37.772892: W tensorflow/core/common_runtime/gpu/gpu_device.cc:2251] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...

# %%
import keras

# %%
# %%time

# Train a Gradient Boosted Trees model.
model = tfdf.keras.GradientBoostedTreesModel()

# Add evaluation metrics
model.compile(
    metrics=["accuracy"]
)
model.fit(x=train_ds)

# # Train a Gradient Boosted Trees model.
# model = tfdf.keras.GradientBoostedTreesModel(num_trees=1500)
# model.fit(train_ds)
# Out:
# Use /tmp/tmpiv9p0g4t as temporary training directory
# Reading training dataset...
# [WARNING 26-07-04 08:38:37.9601 UTC gradient_boosted_trees.cc:1840] "goss_alpha" set but "sampling_method" not equal to "GOSS".
# [WARNING 26-07-04 08:38:37.9602 UTC gradient_boosted_trees.cc:1851] "goss_beta" set but "sampling_method" not equal to "GOSS".
# [WARNING 26-07-04 08:38:37.9602 UTC gradient_boosted_trees.cc:1865] "selective_gradient_boosting_ratio" set but "sampling_method" not equal to "SELGB".
# Training dataset read in 0:00:03.865957. Found 395218 examples.
# Training model...
# Model trained in 0:01:41.157141
# Compiling model...
# [INFO 26-07-04 08:40:22.9915 UTC kernel.cc:1233] Loading model from path /tmp/tmpiv9p0g4t/model/ with prefix dd9391f8ae55458d
# [INFO 26-07-04 08:40:23.0061 UTC quick_scorer_extended.cc:911] The binary was compiled without AVX2 support, but your CPU supports it. Enable it for faster model inference.
# [INFO 26-07-04 08:40:23.0075 UTC abstract_model.cc:1362] Engine "GradientBoostedTreesQuickScorerExtended" built
# [INFO 26-07-04 08:40:23.0075 UTC kernel.cc:1061] Use fast generic engine
# Model compiled.
# CPU times: user 12min 13s, sys: 4.59 s, total: 12min 18s
# Wall time: 1min 47s

# %%
# Evaluate the model
evaluate = model.evaluate(val_ds, return_dict=True)
print()

for name, value in evaluate.items():
    print(f"{name}: {value:.4f}")
# Out:
# WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
#  1/57 [..............................] - ETA: 2:44 - loss: 0.0000e+00 - accuracy: 0.8670
# 13/57 [=====>........................] - ETA: 0s - loss: 0.0000e+00 - accuracy: 0.8858
# 28/57 [=============>................] - ETA: 0s - loss: 0.0000e+00 - accuracy: 0.8883
# 41/57 [====================>.........] - ETA: 0s - loss: 0.0000e+00 - accuracy: 0.8888
# 53/57 [==========================>...] - ETA: 0s - loss: 0.0000e+00 - accuracy: 0.8883
# 57/57 [==============================] - 3s 4ms/step - loss: 0.0000e+00 - accuracy: 0.8887
# loss: 0.0000
# accuracy: 0.8887

# %%
# Model Summary
model.summary()
# Out:
# Model: "gradient_boosted_trees_model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
# =================================================================
# Total params: 1 (1.00 Byte)
# Trainable params: 0 (0.00 Byte)
# Non-trainable params: 1 (1.00 Byte)
# _________________________________________________________________
# Type: "GRADIENT_BOOSTED_TREES"
# Task: CLASSIFICATION
# Label: "__LABEL"
#
# Input Features (14):
# 	DependenceEntropy
# 	DependenceNonUniformity
# 	DependenceNonUniformityNormalized
# 	DependenceVariance
# 	GrayLevelNonUniformity
# 	GrayLevelVariance
# 	HighGrayLevelEmphasis
# 	LargeDependenceEmphasis
# 	LargeDependenceHighGrayLevelEmphasis
# 	LargeDependenceLowGrayLevelEmphasis
# 	LowGrayLevelEmphasis
# 	SmallDependenceEmphasis
# 	SmallDependenceHighGrayLevelEmphasis
# 	SmallDependenceLowGrayLevelEmphasis
#
# Trained with weights
#
# Variable Importance: INV_MEAN_MIN_DEPTH:
#     1. "LargeDependenceHighGrayLevelEmphasis"  0.251924 ################
#     2.              "SmallDependenceEmphasis"  0.226274 ##########
#     3.                    "DependenceEntropy"  0.216706 ########
#     4.  "SmallDependenceLowGrayLevelEmphasis"  0.216120 ########
#     5. "SmallDependenceHighGrayLevelEmphasis"  0.207716 ######
#     6.               "GrayLevelNonUniformity"  0.206084 ######
#     7.                "HighGrayLevelEmphasis"  0.199626 #####
#     8.                    "GrayLevelVariance"  0.190619 ###
#     9.                   "DependenceVariance"  0.190214 ###
#    10.  "LargeDependenceLowGrayLevelEmphasis"  0.189336 ##
#    11.                 "LowGrayLevelEmphasis"  0.187351 ##
#    12.              "LargeDependenceEmphasis"  0.178512
#    13.              "DependenceNonUniformity"  0.176396
#    14.    "DependenceNonUniformityNormalized"  0.175570
#
# Variable Importance: NUM_AS_ROOT:
#     1. "LargeDependenceHighGrayLevelEmphasis" 86.000000 ################
#     2.              "SmallDependenceEmphasis" 40.000000 #######
#     3.                    "DependenceEntropy" 31.000000 #####
#     4.               "GrayLevelNonUniformity" 30.000000 #####
#     5.  "SmallDependenceLowGrayLevelEmphasis" 29.000000 #####
#     6.  "LargeDependenceLowGrayLevelEmphasis" 16.000000 ##
#     7.                   "DependenceVariance" 15.000000 ##
#     8. "SmallDependenceHighGrayLevelEmphasis" 14.000000 ##
#     9.                "HighGrayLevelEmphasis" 12.000000 #
#    10.                 "LowGrayLevelEmphasis"  9.000000 #
#    11.              "LargeDependenceEmphasis"  3.000000
#    12.              "DependenceNonUniformity"  2.000000
#
# Variable Importance: NUM_NODES:
#     1. "LargeDependenceHighGrayLevelEmphasis" 941.000000 ################
#     2.                    "DependenceEntropy" 811.000000 #############
#     3. "SmallDependenceHighGrayLevelEmphasis" 792.000000 ############
#     4.  "SmallDependenceLowGrayLevelEmphasis" 769.000000 ############
#     5.              "SmallDependenceEmphasis" 719.000000 ###########
#     6.                "HighGrayLevelEmphasis" 645.000000 #########
#     7.                    "GrayLevelVariance" 626.000000 #########
#     8.               "GrayLevelNonUniformity" 571.000000 ########
#     9.  "LargeDependenceLowGrayLevelEmphasis" 503.000000 ######
#    10.                   "DependenceVariance" 456.000000 #####
#    11.                 "LowGrayLevelEmphasis" 433.000000 #####
#    12.              "LargeDependenceEmphasis" 250.000000 #
#    13.    "DependenceNonUniformityNormalized" 192.000000
#    14.              "DependenceNonUniformity" 190.000000
#
# Variable Importance: SUM_SCORE:
#     1. "LargeDependenceHighGrayLevelEmphasis" 103765.691159 ################
#     2.                    "DependenceEntropy" 69937.856196 ##########
#     3. "SmallDependenceHighGrayLevelEmphasis" 44734.113175 ######
#     4.                 "LowGrayLevelEmphasis" 30847.853236 ####
#     5.  "SmallDependenceLowGrayLevelEmphasis" 25097.073299 ###
#     6.                "HighGrayLevelEmphasis" 21986.384363 ###
#     7.              "SmallDependenceEmphasis" 8977.346445 #
#     8.               "GrayLevelNonUniformity" 6321.285286
#     9.                    "GrayLevelVariance" 5374.260584
#    10.                   "DependenceVariance" 3846.005422
#    11.  "LargeDependenceLowGrayLevelEmphasis" 3425.996399
#    12.              "LargeDependenceEmphasis" 1362.308674
#    13.              "DependenceNonUniformity" 1072.329041
#    14.    "DependenceNonUniformityNormalized" 1064.442205
#
#
#
# Loss: BINOMIAL_LOG_LIKELIHOOD
# Validation loss value: 0.616562
# Number of trees per iteration: 1
# Node format: NOT_SET
# Number of trees: 287
# Total number of nodes: 16083
#
# Number of nodes by tree:
# Count: 287 Average: 56.0383 StdDev: 7.51087
# Min: 31 Max: 63 Ignored: 0
# ----------------------------------------------
# [ 31, 32)  1   0.35%   0.35%
# [ 32, 34)  3   1.05%   1.39%
# [ 34, 35)  0   0.00%   1.39%
# [ 35, 37)  5   1.74%   3.14% #
# [ 37, 39)  2   0.70%   3.83%
# [ 39, 40)  1   0.35%   4.18%
# [ 40, 42)  3   1.05%   5.23%
# [ 42, 44)  8   2.79%   8.01% #
# [ 44, 45)  0   0.00%   8.01%
# [ 45, 47)  6   2.09%  10.10% #
# [ 47, 49) 17   5.92%  16.03% ##
# [ 49, 50) 17   5.92%  21.95% ##
# [ 50, 52) 12   4.18%  26.13% #
# [ 52, 54) 17   5.92%  32.06% ##
# [ 54, 55)  0   0.00%  32.06%
# [ 55, 57) 22   7.67%  39.72% ###
# [ 57, 59) 24   8.36%  48.08% ###
# [ 59, 60) 23   8.01%  56.10% ###
# [ 60, 62) 45  15.68%  71.78% ######
# [ 62, 63] 81  28.22% 100.00% ##########
#
# Depth by leafs:
# Count: 8185 Average: 4.91643 StdDev: 0.375297
# Min: 2 Max: 5 Ignored: 0
# ----------------------------------------------
# [ 2, 3)   52   0.64%   0.64%
# [ 3, 4)  107   1.31%   1.94%
# [ 4, 5)  314   3.84%   5.78%
# [ 5, 5] 7712  94.22% 100.00% ##########
#
# Number of training obs by leaf:
# Count: 8185 Average: 12468.7 StdDev: 43339
# Min: 5 Max: 350853 Ignored: 0
# ----------------------------------------------
# [      5,  17547) 7249  88.56%  88.56% ##########
# [  17547,  35089)  323   3.95%  92.51%
# [  35089,  52632)  161   1.97%  94.48%
# [  52632,  70174)   97   1.19%  95.66%
# [  70174,  87717)   63   0.77%  96.43%
# [  87717, 105259)   29   0.35%  96.79%
# [ 105259, 122802)   16   0.20%  96.98%
# [ 122802, 140344)   13   0.16%  97.14%
# [ 140344, 157887)   24   0.29%  97.43%
# [ 157887, 175429)   25   0.31%  97.74%
# [ 175429, 192971)   13   0.16%  97.90%
# [ 192971, 210514)   20   0.24%  98.14%
# [ 210514, 228056)   13   0.16%  98.30%
# [ 228056, 245599)   19   0.23%  98.53%
# [ 245599, 263141)   31   0.38%  98.91%
# [ 263141, 280684)   20   0.24%  99.16%
# [ 280684, 298226)   11   0.13%  99.29%
# [ 298226, 315769)   20   0.24%  99.54%
# [ 315769, 333311)   24   0.29%  99.83%
# [ 333311, 350853]   14   0.17% 100.00%
#
# Attribute in nodes:
# 	941 : LargeDependenceHighGrayLevelEmphasis [NUMERICAL]
# 	811 : DependenceEntropy [NUMERICAL]
# 	792 : SmallDependenceHighGrayLevelEmphasis [NUMERICAL]
# 	769 : SmallDependenceLowGrayLevelEmphasis [NUMERICAL]
# 	719 : SmallDependenceEmphasis [NUMERICAL]
# 	645 : HighGrayLevelEmphasis [NUMERICAL]
# 	626 : GrayLevelVariance [NUMERICAL]
# 	571 : GrayLevelNonUniformity [NUMERICAL]
# 	503 : LargeDependenceLowGrayLevelEmphasis [NUMERICAL]
# 	456 : DependenceVariance [NUMERICAL]
# 	433 : LowGrayLevelEmphasis [NUMERICAL]
# 	250 : LargeDependenceEmphasis [NUMERICAL]
# 	192 : DependenceNonUniformityNormalized [NUMERICAL]
# 	190 : DependenceNonUniformity [NUMERICAL]
#
# Attribute in nodes with depth <= 0:
# 	86 : LargeDependenceHighGrayLevelEmphasis [NUMERICAL]
# 	40 : SmallDependenceEmphasis [NUMERICAL]
# 	31 : DependenceEntropy [NUMERICAL]
# 	30 : GrayLevelNonUniformity [NUMERICAL]
# 	29 : SmallDependenceLowGrayLevelEmphasis [NUMERICAL]
# 	16 : LargeDependenceLowGrayLevelEmphasis [NUMERICAL]
# 	15 : DependenceVariance [NUMERICAL]
# 	14 : SmallDependenceHighGrayLevelEmphasis [NUMERICAL]
# 	12 : HighGrayLevelEmphasis [NUMERICAL]
# 	9 : LowGrayLevelEmphasis [NUMERICAL]
# 	3 : LargeDependenceEmphasis [NUMERICAL]
# 	2 : DependenceNonUniformity [NUMERICAL]
#
# Attribute in nodes with depth <= 1:
# 	140 : LargeDependenceHighGrayLevelEmphasis [NUMERICAL]
# 	116 : SmallDependenceEmphasis [NUMERICAL]
# 	109 : SmallDependenceLowGrayLevelEmphasis [NUMERICAL]
# 	94 : DependenceEntropy [NUMERICAL]
# 	79 : GrayLevelNonUniformity [NUMERICAL]
# 	73 : SmallDependenceHighGrayLevelEmphasis [NUMERICAL]
# 	63 : HighGrayLevelEmphasis [NUMERICAL]
# 	42 : DependenceVariance [NUMERICAL]
# 	40 : LowGrayLevelEmphasis [NUMERICAL]
# 	36 : GrayLevelVariance [NUMERICAL]
# 	31 : LargeDependenceLowGrayLevelEmphasis [NUMERICAL]
# 	16 : LargeDependenceEmphasis [NUMERICAL]
# 	13 : DependenceNonUniformity [NUMERICAL]
# 	9 : DependenceNonUniformityNormalized [NUMERICAL]
#
# Attribute in nodes with depth <= 2:
# 	255 : LargeDependenceHighGrayLevelEmphasis [NUMERICAL]
# 	234 : SmallDependenceEmphasis [NUMERICAL]
# 	209 : SmallDependenceLowGrayLevelEmphasis [NUMERICAL]
# 	196 : SmallDependenceHighGrayLevelEmphasis [NUMERICAL]
# 	179 : DependenceEntropy [NUMERICAL]
# 	152 : HighGrayLevelEmphasis [NUMERICAL]
# 	152 : GrayLevelNonUniformity [NUMERICAL]
# 	132 : GrayLevelVariance [NUMERICAL]
# 	123 : DependenceVariance [NUMERICAL]
# 	103 : LargeDependenceLowGrayLevelEmphasis [NUMERICAL]
# 	89 : LowGrayLevelEmphasis [NUMERICAL]
# 	55 : LargeDependenceEmphasis [NUMERICAL]
# 	40 : DependenceNonUniformityNormalized [NUMERICAL]
# 	38 : DependenceNonUniformity [NUMERICAL]
#
# Attribute in nodes with depth <= 3:
# 	479 : LargeDependenceHighGrayLevelEmphasis [NUMERICAL]
# 	420 : SmallDependenceHighGrayLevelEmphasis [NUMERICAL]
# 	403 : DependenceEntropy [NUMERICAL]
# 	398 : SmallDependenceEmphasis [NUMERICAL]
# 	391 : SmallDependenceLowGrayLevelEmphasis [NUMERICAL]
# 	332 : GrayLevelVariance [NUMERICAL]
# 	312 : HighGrayLevelEmphasis [NUMERICAL]
# 	300 : GrayLevelNonUniformity [NUMERICAL]
# 	260 : DependenceVariance [NUMERICAL]
# 	248 : LargeDependenceLowGrayLevelEmphasis [NUMERICAL]
# 	216 : LowGrayLevelEmphasis [NUMERICAL]
# 	105 : LargeDependenceEmphasis [NUMERICAL]
# 	93 : DependenceNonUniformityNormalized [NUMERICAL]
# 	85 : DependenceNonUniformity [NUMERICAL]
#
# Attribute in nodes with depth <= 5:
# 	941 : LargeDependenceHighGrayLevelEmphasis [NUMERICAL]
# 	811 : DependenceEntropy [NUMERICAL]
# 	792 : SmallDependenceHighGrayLevelEmphasis [NUMERICAL]
# 	769 : SmallDependenceLowGrayLevelEmphasis [NUMERICAL]
# 	719 : SmallDependenceEmphasis [NUMERICAL]
# 	645 : HighGrayLevelEmphasis [NUMERICAL]
# 	626 : GrayLevelVariance [NUMERICAL]
# 	571 : GrayLevelNonUniformity [NUMERICAL]
# 	503 : LargeDependenceLowGrayLevelEmphasis [NUMERICAL]
# 	456 : DependenceVariance [NUMERICAL]
# 	433 : LowGrayLevelEmphasis [NUMERICAL]
# 	250 : LargeDependenceEmphasis [NUMERICAL]
# 	192 : DependenceNonUniformityNormalized [NUMERICAL]
# 	190 : DependenceNonUniformity [NUMERICAL]
#
# Condition type in nodes:
# 	7898 : HigherCondition
# Condition type in nodes with depth <= 0:
# 	287 : HigherCondition
# Condition type in nodes with depth <= 1:
# 	861 : HigherCondition
# Condition type in nodes with depth <= 2:
# 	1957 : HigherCondition
# Condition type in nodes with depth <= 3:
# 	4042 : HigherCondition
# Condition type in nodes with depth <= 5:
# 	7898 : HigherCondition
#
# Training logs:
# Number of iteration to final model: 287
# 	Iter:1 train-loss:1.287256 valid-loss:1.290230  train-accuracy:0.834652 valid-accuracy:0.824267
# 	Iter:2 train-loss:1.205924 valid-loss:1.211372  train-accuracy:0.839581 valid-accuracy:0.828012
# 	Iter:3 train-loss:1.137354 valid-loss:1.144660  train-accuracy:0.842313 valid-accuracy:0.832075
# 	Iter:4 train-loss:1.079034 valid-loss:1.087762  train-accuracy:0.843852 valid-accuracy:0.834961
# 	Iter:5 train-loss:1.028388 valid-loss:1.039106  train-accuracy:0.844503 valid-accuracy:0.834953
# 	Iter:6 train-loss:0.984978 valid-loss:0.997148  train-accuracy:0.846094 valid-accuracy:0.838542
# 	Iter:16 train-loss:0.747566 valid-loss:0.772532  train-accuracy:0.858724 valid-accuracy:0.849092
# 	Iter:26 train-loss:0.668607 valid-loss:0.700818  train-accuracy:0.865074 valid-accuracy:0.854764
# 	Iter:36 train-loss:0.633842 valid-loss:0.672543  train-accuracy:0.868458 valid-accuracy:0.857714
# 	Iter:46 train-loss:0.614929 valid-loss:0.659493  train-accuracy:0.870951 valid-accuracy:0.859131
# 	Iter:56 train-loss:0.600883 valid-loss:0.651015  train-accuracy:0.873740 valid-accuracy:0.860834
# 	Iter:66 train-loss:0.589963 valid-loss:0.645043  train-accuracy:0.875806 valid-accuracy:0.862496
# 	Iter:76 train-loss:0.580429 valid-loss:0.639632  train-accuracy:0.877548 valid-accuracy:0.863490
# 	Iter:86 train-loss:0.573503 valid-loss:0.636911  train-accuracy:0.879028 valid-accuracy:0.863617
# 	Iter:96 train-loss:0.567954 valid-loss:0.634472  train-accuracy:0.880297 valid-accuracy:0.864500
# 	Iter:106 train-loss:0.562168 valid-loss:0.631552  train-accuracy:0.881210 valid-accuracy:0.865155
# 	Iter:116 train-loss:0.557458 valid-loss:0.629110  train-accuracy:0.882124 valid-accuracy:0.865648
# 	Iter:126 train-loss:0.552569 valid-loss:0.627703  train-accuracy:0.883133 valid-accuracy:0.866675
# 	Iter:136 train-loss:0.547250 valid-loss:0.626112  train-accuracy:0.884010 valid-accuracy:0.866408
# 	Iter:146 train-loss:0.543032 valid-loss:0.624497  train-accuracy:0.885173 valid-accuracy:0.866914
# 	Iter:156 train-loss:0.539462 valid-loss:0.623155  train-accuracy:0.885857 valid-accuracy:0.866879
# 	Iter:166 train-loss:0.535851 valid-loss:0.622655  train-accuracy:0.886600 valid-accuracy:0.866952
# 	Iter:176 train-loss:0.532846 valid-loss:0.622167  train-accuracy:0.887367 valid-accuracy:0.866564
# 	Iter:186 train-loss:0.529378 valid-loss:0.621471  train-accuracy:0.888139 valid-accuracy:0.866833
# 	Iter:196 train-loss:0.525499 valid-loss:0.620117  train-accuracy:0.889052 valid-accuracy:0.867768
# 	Iter:206 train-loss:0.522257 valid-loss:0.619270  train-accuracy:0.889551 valid-accuracy:0.867970
# 	Iter:216 train-loss:0.519302 valid-loss:0.618783  train-accuracy:0.890163 valid-accuracy:0.868078
# 	Iter:226 train-loss:0.516378 valid-loss:0.618246  train-accuracy:0.891013 valid-accuracy:0.867873
# 	Iter:236 train-loss:0.513748 valid-loss:0.618026  train-accuracy:0.891643 valid-accuracy:0.868170
# 	Iter:246 train-loss:0.510780 valid-loss:0.617834  train-accuracy:0.892414 valid-accuracy:0.868528
# 	Iter:256 train-loss:0.508081 valid-loss:0.617272  train-accuracy:0.893101 valid-accuracy:0.868587
# 	Iter:266 train-loss:0.505582 valid-loss:0.617114  train-accuracy:0.893786 valid-accuracy:0.867534
# 	Iter:276 train-loss:0.503584 valid-loss:0.616786  train-accuracy:0.894241 valid-accuracy:0.867418
# 	Iter:286 train-loss:0.500363 valid-loss:0.616592  train-accuracy:0.895018 valid-accuracy:0.868242
# 	Iter:296 train-loss:0.498087 valid-loss:0.616696  train-accuracy:0.895610 valid-accuracy:0.868194

# %%
# Model features
model.make_inspector().features()
# Out:
# ["DependenceEntropy" (1; #0),
#  "DependenceNonUniformity" (1; #1),
#  "DependenceNonUniformityNormalized" (1; #2),
#  "DependenceVariance" (1; #3),
#  "GrayLevelNonUniformity" (1; #4),
#  "GrayLevelVariance" (1; #5),
#  "HighGrayLevelEmphasis" (1; #6),
#  "LargeDependenceEmphasis" (1; #7),
#  "LargeDependenceHighGrayLevelEmphasis" (1; #8),
#  "LargeDependenceLowGrayLevelEmphasis" (1; #9),
#  "LowGrayLevelEmphasis" (1; #10),
#  "SmallDependenceEmphasis" (1; #11),
#  "SmallDependenceHighGrayLevelEmphasis" (1; #12),
#  "SmallDependenceLowGrayLevelEmphasis" (1; #13)]

# %%
# Feature importance
model.make_inspector().variable_importances()
# Out:
# {'INV_MEAN_MIN_DEPTH': [("LargeDependenceHighGrayLevelEmphasis" (1; #8),
#    0.2519236928616062),
#   ("SmallDependenceEmphasis" (1; #11), 0.2262736082008568),
#   ("DependenceEntropy" (1; #0), 0.21670560410845024),
#   ("SmallDependenceLowGrayLevelEmphasis" (1; #13), 0.21612031072122895),
#   ("SmallDependenceHighGrayLevelEmphasis" (1; #12), 0.2077155422407849),
#   ("GrayLevelNonUniformity" (1; #4), 0.2060835237012734),
#   ("HighGrayLevelEmphasis" (1; #6), 0.1996262207726205),
#   ("GrayLevelVariance" (1; #5), 0.19061943787250227),
#   ("DependenceVariance" (1; #3), 0.19021408959996217),
#   ("LargeDependenceLowGrayLevelEmphasis" (1; #9), 0.18933567671775728),
#   ("LowGrayLevelEmphasis" (1; #10), 0.1873514210573217),
#   ("LargeDependenceEmphasis" (1; #7), 0.17851234319794718),
#   ("DependenceNonUniformity" (1; #1), 0.17639616069674482),
#   ("DependenceNonUniformityNormalized" (1; #2), 0.17557012181076076)],
#  'NUM_AS_ROOT': [("LargeDependenceHighGrayLevelEmphasis" (1; #8), 86.0),
#   ("SmallDependenceEmphasis" (1; #11), 40.0),
#   ("DependenceEntropy" (1; #0), 31.0),
#   ("GrayLevelNonUniformity" (1; #4), 30.0),
#   ("SmallDependenceLowGrayLevelEmphasis" (1; #13), 29.0),
#   ("LargeDependenceLowGrayLevelEmphasis" (1; #9), 16.0),
#   ("DependenceVariance" (1; #3), 15.0),
#   ("SmallDependenceHighGrayLevelEmphasis" (1; #12), 14.0),
#   ("HighGrayLevelEmphasis" (1; #6), 12.0),
#   ("LowGrayLevelEmphasis" (1; #10), 9.0),
#   ("LargeDependenceEmphasis" (1; #7), 3.0),
#   ("DependenceNonUniformity" (1; #1), 2.0)],
#  'SUM_SCORE': [("LargeDependenceHighGrayLevelEmphasis" (1; #8),
#    103765.69115852607),
#   ("DependenceEntropy" (1; #0), 69937.85619551752),
#   ("SmallDependenceHighGrayLevelEmphasis" (1; #12), 44734.11317491287),
#   ("LowGrayLevelEmphasis" (1; #10), 30847.85323630521),
#   ("SmallDependenceLowGrayLevelEmphasis" (1; #13), 25097.073299225627),
#   ("HighGrayLevelEmphasis" (1; #6), 21986.384362545286),
#   ("SmallDependenceEmphasis" (1; #11), 8977.346445348965),
#   ("GrayLevelNonUniformity" (1; #4), 6321.285285780462),
#   ("GrayLevelVariance" (1; #5), 5374.260584006255),
#   ("DependenceVariance" (1; #3), 3846.0054220773695),
#   ("LargeDependenceLowGrayLevelEmphasis" (1; #9), 3425.996399476353),
#   ("LargeDependenceEmphasis" (1; #7), 1362.308673530674),
#   ("DependenceNonUniformity" (1; #1), 1072.3290406781084),
#   ("DependenceNonUniformityNormalized" (1; #2), 1064.442205293823)],
#  'NUM_NODES': [("LargeDependenceHighGrayLevelEmphasis" (1; #8), 941.0),
#   ("DependenceEntropy" (1; #0), 811.0),
#   ("SmallDependenceHighGrayLevelEmphasis" (1; #12), 792.0),
#   ("SmallDependenceLowGrayLevelEmphasis" (1; #13), 769.0),
#   ("SmallDependenceEmphasis" (1; #11), 719.0),
#   ("HighGrayLevelEmphasis" (1; #6), 645.0),
#   ("GrayLevelVariance" (1; #5), 626.0),
#   ("GrayLevelNonUniformity" (1; #4), 571.0),
#   ("LargeDependenceLowGrayLevelEmphasis" (1; #9), 503.0),
#   ("DependenceVariance" (1; #3), 456.0),
#   ("LowGrayLevelEmphasis" (1; #10), 433.0),
#   ("LargeDependenceEmphasis" (1; #7), 250.0),
#   ("DependenceNonUniformityNormalized" (1; #2), 192.0),
#   ("DependenceNonUniformity" (1; #1), 190.0)]}

# %%
# Model self evaluation
model.make_inspector().evaluation()
# Out:
# Evaluation(num_examples=None, accuracy=0.8682690858840942, loss=0.6165618300437927, rmse=None, ndcg=None, aucs=None, auuc=None, qini=None)

# %%
logs = model.make_inspector().training_logs()

plt.figure(figsize=(12, 4))
plt.subplot(1, 2, 1)
plt.plot([log.num_trees for log in logs], [log.evaluation.accuracy for log in logs])
plt.xlabel("Number of trees")
plt.ylabel("Accuracy (out-of-bag)")
plt.subplot(1, 2, 2)
plt.plot([log.num_trees for log in logs], [log.evaluation.loss for log in logs])
plt.xlabel("Number of trees")
plt.ylabel("Logloss (out-of-bag)")
plt.show()

# %% [markdown]
# Calculate the score of our hold-out validation dataset

# %%
predictions = model.predict(val_ds)
y_true      = validation_data["label"]

from sklearn.metrics import roc_auc_score
ROC_AUC = roc_auc_score(y_true, predictions)
print("The ROC AUC score is %.5f" % ROC_AUC )
# Out:
#  1/57 [..............................] - ETA: 4s
# 14/57 [======>.......................] - ETA: 0s
# 27/57 [=============>................] - ETA: 0s
# 39/57 [===================>..........] - ETA: 0s
# 52/57 [==========================>...] - ETA: 0s
# 57/57 [==============================] - 0s 4ms/step
# The ROC AUC score is 0.94613

# %%
# Compute binary classification metrics with sklearn
import numpy as np
from sklearn.metrics import (
    accuracy_score,
    precision_score,
    recall_score,
    f1_score,
    roc_auc_score,
    average_precision_score,
    confusion_matrix,
    classification_report,
    matthews_corrcoef,
    log_loss,
    brier_score_loss,
)

# Get predictions (probabilities or class labels)
preds = model.predict(test_ds)
# If model outputs probabilities, convert to labels by threshold 0.5
if preds.ndim == 2:
    # For TFDF classification, preds may be class probabilities with shape (N, 2)
    if preds.shape[1] == 2:
        pos_probs = preds[:, 1]
    else:
        # If single-probability column (positive class)
        pos_probs = preds[:, -1]
    y_pred = (pos_probs >= 0.5).astype(int)
else:
    # Already class labels
    y_pred = preds.astype(int)
    pos_probs = None

# Ground truth labels (must be 0/1 integers)
y_true = test_data["label"].astype(int).to_numpy()

# Core metrics
metrics = {}
metrics["accuracy"] = accuracy_score(y_true, y_pred)
metrics["precision"] = precision_score(y_true, y_pred, zero_division=0)
metrics["recall"] = recall_score(y_true, y_pred, zero_division=0)
metrics["f1"] = f1_score(y_true, y_pred, zero_division=0)
metrics["mcc"] = matthews_corrcoef(y_true, y_pred)

# Probabilistic metrics (only if we have probabilities)
if pos_probs is not None:
    metrics["roc_auc"] = roc_auc_score(y_true, pos_probs)
    metrics["pr_auc"] = average_precision_score(y_true, pos_probs)
    metrics["log_loss"] = log_loss(y_true, pos_probs, labels=[0,1])
    metrics["brier_score"] = brier_score_loss(y_true, pos_probs)

# Confusion matrix and detailed report
cm = confusion_matrix(y_true, y_pred, labels=[0,1])
report = classification_report(y_true, y_pred, digits=4)

print("Sklearn binary metrics:")
for k, v in metrics.items():
    print(f"{k}: {v:.4f}")
print("\nConfusion matrix:\n", cm)
print("\nClassification report:\n", report)
# Out:
#   1/113 [..............................] - ETA: 7s
#  15/113 [==>...........................] - ETA: 0s
#  30/113 [======>.......................] - ETA: 0s
#  43/113 [==========>...................] - ETA: 0s
#  57/113 [==============>...............] - ETA: 0s
#  70/113 [=================>............] - ETA: 0s
#  83/113 [=====================>........] - ETA: 0s
#  98/113 [=========================>....] - ETA: 0s
# 112/113 [============================>.] - ETA: 0s
# 113/113 [==============================] - 0s 4ms/step
# Sklearn binary metrics:
# accuracy: 0.8887
# precision: 0.3484
# recall: 0.8558
# f1: 0.4952
# mcc: 0.5020
# roc_auc: 0.9472
# pr_auc: 0.6931
# log_loss: 0.2681
# brier_score: 0.0815
#
# Confusion matrix:
#  [[94186 11530]
#  [ 1039  6165]]
#
# Classification report:
#                precision    recall  f1-score   support
#
#            0     0.9891    0.8909    0.9374    105716
#            1     0.3484    0.8558    0.4952      7204
#
#     accuracy                         0.8887    112920
#    macro avg     0.6687    0.8734    0.7163    112920
# weighted avg     0.9482    0.8887    0.9092    112920
