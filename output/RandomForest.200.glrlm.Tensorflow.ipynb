# %%
# Import packages and modules
import numpy  as np
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow_decision_forests as tfdf

from sklearn.model_selection import train_test_split
# Out:
# 2026-07-04 08:54:53.942090: I tensorflow/core/util/port.cc:113] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2026-07-04 08:54:53.989320: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2026-07-04 08:54:58.226727: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
# Check the version of TensorFlow Decision Forests
print("Found TensorFlow Decision Forests v" + tfdf.__version__)
# Out:
# Found TensorFlow Decision Forests v1.9.1

# %%
datasetPath = 'dataset/firstorder/kernel5-radius5/dataset.csv'

# %%
# Parameters
datasetPath = "dataset/glrlm/kernel5-radius5/200.dataset.csv"

# %%
# train/validation/test = 70/10/20
dataset = pd.read_csv(datasetPath)

train_data, temp_data = train_test_split(dataset, test_size=0.3, random_state=42)
validation_data, test_data = train_test_split(temp_data, test_size=2/3, random_state=42)

# %%
from sklearn.utils.class_weight import compute_class_weight

# tinh class weight tren tap train
classes = np.array([0, 1])
weights = compute_class_weight(class_weight="balanced", classes=classes, y=train_data["label"])
class_weight = {0: weights[0], 1: weights[1]}

# gan sample_weight cho tung dong
train_data["sample_weight"] = train_data["label"].map(class_weight)
validation_data["sample_weight"] = validation_data["label"].map(class_weight)
test_data["sample_weight"] = test_data["label"].map(class_weight)

# Convert the dataset into a TensorFlow dataset.
train_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    train_data, label="label", weight="sample_weight"
)         
val_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    validation_data, label="label", weight="sample_weight"
)
test_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    test_data, label="label", weight="sample_weight"
)
# Out:
# 2026-07-04 08:55:10.258717: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:984] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2026-07-04 08:55:10.260867: W tensorflow/core/common_runtime/gpu/gpu_device.cc:2251] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...

# %%
import keras

# %%
# %%time

# Train a Random Forest model.
model = tfdf.keras.RandomForestModel()

# Add evaluation metrics
model.compile(
    metrics=["accuracy"]
)
model.fit(x=train_ds)

# # Train a Gradient Boosted Trees model.
# model = tfdf.keras.GradientBoostedTreesModel(num_trees=1500)
# model.fit(train_ds)
# Out:
# Use /tmp/tmpg6qtf4d1 as temporary training directory
# Reading training dataset...
# Training dataset read in 0:00:03.094668. Found 157612 examples.
# Training model...
# [INFO 26-07-04 08:55:30.1745 UTC kernel.cc:1233] Loading model from path /tmp/tmpg6qtf4d1/model/ with prefix 8d44073eca314da2
# Model trained in 0:00:18.002343
# Compiling model...
# [INFO 26-07-04 08:55:31.3617 UTC decision_forest.cc:734] Model loaded with 300 root(s), 1019968 node(s), and 16 input feature(s).
# [INFO 26-07-04 08:55:31.3617 UTC abstract_model.cc:1362] Engine "RandomForestOptPred" built
# [INFO 26-07-04 08:55:31.3617 UTC kernel.cc:1061] Use fast generic engine
# Model compiled.
# CPU times: user 3min 3s, sys: 1.35 s, total: 3min 4s
# Wall time: 24.2 s

# %%
# Evaluate the model
evaluate = model.evaluate(val_ds, return_dict=True)
print()

for name, value in evaluate.items():
    print(f"{name}: {value:.4f}")
# Out:
# WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
#  1/23 [>.............................] - ETA: 1:04 - loss: 0.0000e+00 - accuracy: 0.9380
#  3/23 [==>...........................] - ETA: 0s - loss: 0.0000e+00 - accuracy: 0.9287
#  5/23 [=====>........................] - ETA: 0s - loss: 0.0000e+00 - accuracy: 0.9266
#  7/23 [========>.....................] - ETA: 0s - loss: 0.0000e+00 - accuracy: 0.9279
#  9/23 [==========>...................] - ETA: 0s - loss: 0.0000e+00 - accuracy: 0.9281
# 11/23 [=============>................] - ETA: 0s - loss: 0.0000e+00 - accuracy: 0.9265
# 13/23 [===============>..............] - ETA: 0s - loss: 0.0000e+00 - accuracy: 0.9257
# 15/23 [==================>...........] - ETA: 0s - loss: 0.0000e+00 - accuracy: 0.9262
# 17/23 [=====================>........] - ETA: 0s - loss: 0.0000e+00 - accuracy: 0.9251
# 19/23 [=======================>......] - ETA: 0s - loss: 0.0000e+00 - accuracy: 0.9260
# 21/23 [==========================>...] - ETA: 0s - loss: 0.0000e+00 - accuracy: 0.9264
# 23/23 [==============================] - 4s 29ms/step - loss: 0.0000e+00 - accuracy: 0.9272
# loss: 0.0000
# accuracy: 0.9272

# %%
# Model Summary
model.summary()
# Out:
# Model: "random_forest_model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
# =================================================================
# Total params: 1 (1.00 Byte)
# Trainable params: 0 (0.00 Byte)
# Non-trainable params: 1 (1.00 Byte)
# _________________________________________________________________
# Type: "RANDOM_FOREST"
# Task: CLASSIFICATION
# Label: "__LABEL"
#
# Input Features (16):
# 	GrayLevelNonUniformity
# 	GrayLevelNonUniformityNormalized
# 	GrayLevelVariance
# 	HighGrayLevelRunEmphasis
# 	LongRunEmphasis
# 	LongRunHighGrayLevelEmphasis
# 	LongRunLowGrayLevelEmphasis
# 	LowGrayLevelRunEmphasis
# 	RunEntropy
# 	RunLengthNonUniformity
# 	RunLengthNonUniformityNormalized
# 	RunPercentage
# 	RunVariance
# 	ShortRunEmphasis
# 	ShortRunHighGrayLevelEmphasis
# 	ShortRunLowGrayLevelEmphasis
#
# Trained with weights
#
# Variable Importance: INV_MEAN_MIN_DEPTH:
#     1.     "LongRunHighGrayLevelEmphasis"  0.167322 ################
#     2.         "HighGrayLevelRunEmphasis"  0.162471 ###############
#     3.     "ShortRunLowGrayLevelEmphasis"  0.148296 ############
#     4.    "ShortRunHighGrayLevelEmphasis"  0.130445 ########
#     5.                       "RunEntropy"  0.124697 #######
#     6.          "LowGrayLevelRunEmphasis"  0.123472 #######
#     7.           "GrayLevelNonUniformity"  0.116200 ######
#     8.      "LongRunLowGrayLevelEmphasis"  0.104463 ###
#     9. "GrayLevelNonUniformityNormalized"  0.093677 #
#    10.                      "RunVariance"  0.091383 #
#    11.                "GrayLevelVariance"  0.090037 #
#    12.                 "ShortRunEmphasis"  0.088216
#    13. "RunLengthNonUniformityNormalized"  0.087597
#    14.                  "LongRunEmphasis"  0.085511
#    15.                    "RunPercentage"  0.084880
#    16.           "RunLengthNonUniformity"  0.084137
#
# Variable Importance: NUM_AS_ROOT:
#     1.     "ShortRunLowGrayLevelEmphasis" 80.000000 ################
#     2.          "LowGrayLevelRunEmphasis" 63.000000 ############
#     3.         "HighGrayLevelRunEmphasis" 60.000000 ###########
#     4.     "LongRunHighGrayLevelEmphasis" 34.000000 ######
#     5.      "LongRunLowGrayLevelEmphasis" 34.000000 ######
#     6.                       "RunEntropy" 14.000000 ##
#     7.           "GrayLevelNonUniformity"  7.000000 #
#     8.    "ShortRunHighGrayLevelEmphasis"  5.000000
#     9. "GrayLevelNonUniformityNormalized"  1.000000
#    10.                "GrayLevelVariance"  1.000000
#    11.                      "RunVariance"  1.000000
#
# Variable Importance: NUM_NODES:
#     1.           "GrayLevelNonUniformity" 40256.000000 ################
#     2.                       "RunEntropy" 40015.000000 ###############
#     3.     "LongRunHighGrayLevelEmphasis" 38901.000000 ##############
#     4.                "GrayLevelVariance" 37569.000000 #############
#     5. "GrayLevelNonUniformityNormalized" 34298.000000 ##########
#     6.     "ShortRunLowGrayLevelEmphasis" 33258.000000 #########
#     7.    "ShortRunHighGrayLevelEmphasis" 32130.000000 #######
#     8.         "HighGrayLevelRunEmphasis" 31698.000000 #######
#     9.      "LongRunLowGrayLevelEmphasis" 31499.000000 #######
#    10.          "LowGrayLevelRunEmphasis" 30960.000000 ######
#    11.                      "RunVariance" 30661.000000 ######
#    12. "RunLengthNonUniformityNormalized" 26795.000000 ##
#    13.                 "ShortRunEmphasis" 26737.000000 ##
#    14.                  "LongRunEmphasis" 25912.000000 #
#    15.           "RunLengthNonUniformity" 25037.000000
#    16.                    "RunPercentage" 24108.000000
#
# Variable Importance: SUM_SCORE:
#     1.         "HighGrayLevelRunEmphasis" 3425806.914190 ################
#     2.     "LongRunHighGrayLevelEmphasis" 3363956.719056 ###############
#     3.     "ShortRunLowGrayLevelEmphasis" 2895111.252857 ############
#     4.          "LowGrayLevelRunEmphasis" 2271802.240450 #########
#     5.    "ShortRunHighGrayLevelEmphasis" 2240922.443827 #########
#     6.                       "RunEntropy" 2080319.200686 ########
#     7.           "GrayLevelNonUniformity" 1881097.299846 #######
#     8.      "LongRunLowGrayLevelEmphasis" 1503928.719717 ####
#     9. "GrayLevelNonUniformityNormalized" 1060961.782376 ##
#    10.                "GrayLevelVariance" 1015843.806533 ##
#    11.                      "RunVariance" 1002465.314076 ##
#    12.                 "ShortRunEmphasis" 794381.242469
#    13. "RunLengthNonUniformityNormalized" 783265.110951
#    14.                  "LongRunEmphasis" 738396.963007
#    15.                    "RunPercentage" 673246.754946
#    16.           "RunLengthNonUniformity" 652749.015540
#
#
#
# Winner takes all: true
# Out-of-bag evaluation: accuracy:0.85681 logloss:0.466021
# Number of trees: 300
# Total number of nodes: 1019968
#
# Number of nodes by tree:
# Count: 300 Average: 3399.89 StdDev: 207.935
# Min: 2789 Max: 3945 Ignored: 0
# ----------------------------------------------
# [ 2789, 2846)  2   0.67%   0.67% #
# [ 2846, 2904)  3   1.00%   1.67% #
# [ 2904, 2962)  5   1.67%   3.33% #
# [ 2962, 3020)  8   2.67%   6.00% ##
# [ 3020, 3078)  8   2.67%   8.67% ##
# [ 3078, 3136)  1   0.33%   9.00%
# [ 3136, 3193) 15   5.00%  14.00% ####
# [ 3193, 3251) 21   7.00%  21.00% #####
# [ 3251, 3309) 29   9.67%  30.67% #######
# [ 3309, 3367) 31  10.33%  41.00% ########
# [ 3367, 3425) 39  13.00%  54.00% ##########
# [ 3425, 3483) 32  10.67%  64.67% ########
# [ 3483, 3541) 32  10.67%  75.33% ########
# [ 3541, 3598) 24   8.00%  83.33% ######
# [ 3598, 3656) 17   5.67%  89.00% ####
# [ 3656, 3714) 19   6.33%  95.33% #####
# [ 3714, 3772)  6   2.00%  97.33% ##
# [ 3772, 3830)  3   1.00%  98.33% #
# [ 3830, 3888)  2   0.67%  99.00% #
# [ 3888, 3945]  3   1.00% 100.00% #
#
# Depth by leafs:
# Count: 510134 Average: 12.9069 StdDev: 2.14527
# Min: 3 Max: 15 Ignored: 0
# ----------------------------------------------
# [  3,  4)      7   0.00%   0.00%
# [  4,  5)    139   0.03%   0.03%
# [  5,  6)    806   0.16%   0.19%
# [  6,  7)   2524   0.49%   0.68%
# [  7,  8)   5972   1.17%   1.85%
# [  8,  9)  12066   2.37%   4.22% #
# [  9, 10)  21314   4.18%   8.40% #
# [ 10, 11)  33618   6.59%  14.99% ##
# [ 11, 12)  47484   9.31%  24.29% ###
# [ 12, 13)  62315  12.22%  36.51% ####
# [ 13, 14)  73849  14.48%  50.99% ####
# [ 14, 15)  82572  16.19%  67.17% #####
# [ 15, 15] 167468  32.83% 100.00% ##########
#
# Number of training obs by leaf:
# Count: 510134 Average: 92.6886 StdDev: 393.853
# Min: 5 Max: 14044 Ignored: 0
# ----------------------------------------------
# [     5,   707) 498332  97.69%  97.69% ##########
# [   707,  1409)   6200   1.22%  98.90%
# [  1409,  2111)   2238   0.44%  99.34%
# [  2111,  2813)   1229   0.24%  99.58%
# [  2813,  3515)    682   0.13%  99.72%
# [  3515,  4217)    431   0.08%  99.80%
# [  4217,  4919)    294   0.06%  99.86%
# [  4919,  5621)    186   0.04%  99.89%
# [  5621,  6323)    129   0.03%  99.92%
# [  6323,  7025)    101   0.02%  99.94%
# [  7025,  7727)     93   0.02%  99.96%
# [  7727,  8429)     72   0.01%  99.97%
# [  8429,  9131)     59   0.01%  99.98%
# [  9131,  9833)     26   0.01%  99.99%
# [  9833, 10535)     21   0.00%  99.99%
# [ 10535, 11237)     15   0.00%  99.99%
# [ 11237, 11939)     11   0.00% 100.00%
# [ 11939, 12641)      6   0.00% 100.00%
# [ 12641, 13343)      6   0.00% 100.00%
# [ 13343, 14044]      3   0.00% 100.00%
#
# Attribute in nodes:
# 	40256 : GrayLevelNonUniformity [NUMERICAL]
# 	40015 : RunEntropy [NUMERICAL]
# 	38901 : LongRunHighGrayLevelEmphasis [NUMERICAL]
# 	37569 : GrayLevelVariance [NUMERICAL]
# 	34298 : GrayLevelNonUniformityNormalized [NUMERICAL]
# 	33258 : ShortRunLowGrayLevelEmphasis [NUMERICAL]
# 	32130 : ShortRunHighGrayLevelEmphasis [NUMERICAL]
# 	31698 : HighGrayLevelRunEmphasis [NUMERICAL]
# 	31499 : LongRunLowGrayLevelEmphasis [NUMERICAL]
# 	30960 : LowGrayLevelRunEmphasis [NUMERICAL]
# 	30661 : RunVariance [NUMERICAL]
# 	26795 : RunLengthNonUniformityNormalized [NUMERICAL]
# 	26737 : ShortRunEmphasis [NUMERICAL]
# 	25912 : LongRunEmphasis [NUMERICAL]
# 	25037 : RunLengthNonUniformity [NUMERICAL]
# 	24108 : RunPercentage [NUMERICAL]
#
# Attribute in nodes with depth <= 0:
# 	80 : ShortRunLowGrayLevelEmphasis [NUMERICAL]
# 	63 : LowGrayLevelRunEmphasis [NUMERICAL]
# 	60 : HighGrayLevelRunEmphasis [NUMERICAL]
# 	34 : LongRunLowGrayLevelEmphasis [NUMERICAL]
# 	34 : LongRunHighGrayLevelEmphasis [NUMERICAL]
# 	14 : RunEntropy [NUMERICAL]
# 	7 : GrayLevelNonUniformity [NUMERICAL]
# 	5 : ShortRunHighGrayLevelEmphasis [NUMERICAL]
# 	1 : RunVariance [NUMERICAL]
# 	1 : GrayLevelVariance [NUMERICAL]
# 	1 : GrayLevelNonUniformityNormalized [NUMERICAL]
#
# Attribute in nodes with depth <= 1:
# 	215 : HighGrayLevelRunEmphasis [NUMERICAL]
# 	194 : LongRunHighGrayLevelEmphasis [NUMERICAL]
# 	148 : ShortRunLowGrayLevelEmphasis [NUMERICAL]
# 	97 : LowGrayLevelRunEmphasis [NUMERICAL]
# 	71 : ShortRunHighGrayLevelEmphasis [NUMERICAL]
# 	70 : RunEntropy [NUMERICAL]
# 	43 : LongRunLowGrayLevelEmphasis [NUMERICAL]
# 	27 : GrayLevelNonUniformity [NUMERICAL]
# 	14 : GrayLevelNonUniformityNormalized [NUMERICAL]
# 	12 : GrayLevelVariance [NUMERICAL]
# 	3 : RunVariance [NUMERICAL]
# 	2 : ShortRunEmphasis [NUMERICAL]
# 	2 : LongRunEmphasis [NUMERICAL]
# 	1 : RunPercentage [NUMERICAL]
# 	1 : RunLengthNonUniformityNormalized [NUMERICAL]
#
# Attribute in nodes with depth <= 2:
# 	411 : HighGrayLevelRunEmphasis [NUMERICAL]
# 	405 : LongRunHighGrayLevelEmphasis [NUMERICAL]
# 	250 : ShortRunHighGrayLevelEmphasis [NUMERICAL]
# 	222 : ShortRunLowGrayLevelEmphasis [NUMERICAL]
# 	178 : LowGrayLevelRunEmphasis [NUMERICAL]
# 	163 : RunEntropy [NUMERICAL]
# 	94 : GrayLevelNonUniformity [NUMERICAL]
# 	81 : LongRunLowGrayLevelEmphasis [NUMERICAL]
# 	53 : ShortRunEmphasis [NUMERICAL]
# 	51 : RunVariance [NUMERICAL]
# 	40 : GrayLevelNonUniformityNormalized [NUMERICAL]
# 	38 : RunLengthNonUniformityNormalized [NUMERICAL]
# 	34 : LongRunEmphasis [NUMERICAL]
# 	30 : GrayLevelVariance [NUMERICAL]
# 	25 : RunPercentage [NUMERICAL]
# 	25 : RunLengthNonUniformity [NUMERICAL]
#
# Attribute in nodes with depth <= 3:
# 	846 : LongRunHighGrayLevelEmphasis [NUMERICAL]
# 	644 : HighGrayLevelRunEmphasis [NUMERICAL]
# 	450 : ShortRunHighGrayLevelEmphasis [NUMERICAL]
# 	400 : RunEntropy [NUMERICAL]
# 	390 : ShortRunLowGrayLevelEmphasis [NUMERICAL]
# 	344 : LowGrayLevelRunEmphasis [NUMERICAL]
# 	322 : GrayLevelNonUniformity [NUMERICAL]
# 	216 : LongRunLowGrayLevelEmphasis [NUMERICAL]
# 	179 : GrayLevelNonUniformityNormalized [NUMERICAL]
# 	141 : ShortRunEmphasis [NUMERICAL]
# 	129 : GrayLevelVariance [NUMERICAL]
# 	101 : RunVariance [NUMERICAL]
# 	100 : RunLengthNonUniformityNormalized [NUMERICAL]
# 	85 : RunLengthNonUniformity [NUMERICAL]
# 	74 : LongRunEmphasis [NUMERICAL]
# 	72 : RunPercentage [NUMERICAL]
#
# Attribute in nodes with depth <= 5:
# 	2467 : LongRunHighGrayLevelEmphasis [NUMERICAL]
# 	1739 : RunEntropy [NUMERICAL]
# 	1559 : HighGrayLevelRunEmphasis [NUMERICAL]
# 	1481 : GrayLevelNonUniformity [NUMERICAL]
# 	1308 : ShortRunHighGrayLevelEmphasis [NUMERICAL]
# 	1198 : ShortRunLowGrayLevelEmphasis [NUMERICAL]
# 	1157 : LowGrayLevelRunEmphasis [NUMERICAL]
# 	908 : LongRunLowGrayLevelEmphasis [NUMERICAL]
# 	844 : GrayLevelVariance [NUMERICAL]
# 	842 : GrayLevelNonUniformityNormalized [NUMERICAL]
# 	772 : ShortRunEmphasis [NUMERICAL]
# 	768 : RunLengthNonUniformityNormalized [NUMERICAL]
# 	756 : RunVariance [NUMERICAL]
# 	631 : RunLengthNonUniformity [NUMERICAL]
# 	628 : RunPercentage [NUMERICAL]
# 	570 : LongRunEmphasis [NUMERICAL]
#
# Condition type in nodes:
# 	509834 : HigherCondition
# Condition type in nodes with depth <= 0:
# 	300 : HigherCondition
# Condition type in nodes with depth <= 1:
# 	900 : HigherCondition
# Condition type in nodes with depth <= 2:
# 	2100 : HigherCondition
# Condition type in nodes with depth <= 3:
# 	4493 : HigherCondition
# Condition type in nodes with depth <= 5:
# 	17628 : HigherCondition
# Node format: NOT_SET
#
# Training OOB:
# 	trees: 1, Out-of-bag evaluation: accuracy:0.822944 logloss:6.38175
# 	trees: 11, Out-of-bag evaluation: accuracy:0.831445 logloss:2.60346
# 	trees: 21, Out-of-bag evaluation: accuracy:0.843714 logloss:1.57547
# 	trees: 31, Out-of-bag evaluation: accuracy:0.84929 logloss:1.22837
# 	trees: 41, Out-of-bag evaluation: accuracy:0.852114 logloss:1.04313
# 	trees: 51, Out-of-bag evaluation: accuracy:0.853082 logloss:0.925794
# 	trees: 61, Out-of-bag evaluation: accuracy:0.852903 logloss:0.835503
# 	trees: 71, Out-of-bag evaluation: accuracy:0.854455 logloss:0.769237
# 	trees: 81, Out-of-bag evaluation: accuracy:0.854306 logloss:0.732149
# 	trees: 91, Out-of-bag evaluation: accuracy:0.855709 logloss:0.691329
# 	trees: 101, Out-of-bag evaluation: accuracy:0.85462 logloss:0.656962
# 	trees: 111, Out-of-bag evaluation: accuracy:0.855286 logloss:0.634996
# 	trees: 121, Out-of-bag evaluation: accuracy:0.855328 logloss:0.609553
# 	trees: 131, Out-of-bag evaluation: accuracy:0.855412 logloss:0.59539
# 	trees: 141, Out-of-bag evaluation: accuracy:0.855238 logloss:0.587244
# 	trees: 151, Out-of-bag evaluation: accuracy:0.855193 logloss:0.576576
# 	trees: 161, Out-of-bag evaluation: accuracy:0.856244 logloss:0.564082
# 	trees: 171, Out-of-bag evaluation: accuracy:0.855577 logloss:0.543851
# 	trees: 181, Out-of-bag evaluation: accuracy:0.855324 logloss:0.534633
# 	trees: 191, Out-of-bag evaluation: accuracy:0.856058 logloss:0.530592
# 	trees: 201, Out-of-bag evaluation: accuracy:0.856232 logloss:0.523747
# 	trees: 211, Out-of-bag evaluation: accuracy:0.855785 logloss:0.519411
# 	trees: 221, Out-of-bag evaluation: accuracy:0.856107 logloss:0.517017
# 	trees: 231, Out-of-bag evaluation: accuracy:0.856032 logloss:0.510208
# 	trees: 241, Out-of-bag evaluation: accuracy:0.856447 logloss:0.495529
# 	trees: 251, Out-of-bag evaluation: accuracy:0.856925 logloss:0.490394
# 	trees: 261, Out-of-bag evaluation: accuracy:0.85648 logloss:0.480641
# 	trees: 271, Out-of-bag evaluation: accuracy:0.856433 logloss:0.474084
# 	trees: 281, Out-of-bag evaluation: accuracy:0.856381 logloss:0.470061
# 	trees: 291, Out-of-bag evaluation: accuracy:0.857147 logloss:0.467822
# 	trees: 300, Out-of-bag evaluation: accuracy:0.85681 logloss:0.466021

# %%
# Model features
model.make_inspector().features()
# Out:
# ["GrayLevelNonUniformity" (1; #0),
#  "GrayLevelNonUniformityNormalized" (1; #1),
#  "GrayLevelVariance" (1; #2),
#  "HighGrayLevelRunEmphasis" (1; #3),
#  "LongRunEmphasis" (1; #4),
#  "LongRunHighGrayLevelEmphasis" (1; #5),
#  "LongRunLowGrayLevelEmphasis" (1; #6),
#  "LowGrayLevelRunEmphasis" (1; #7),
#  "RunEntropy" (1; #8),
#  "RunLengthNonUniformity" (1; #9),
#  "RunLengthNonUniformityNormalized" (1; #10),
#  "RunPercentage" (1; #11),
#  "RunVariance" (1; #12),
#  "ShortRunEmphasis" (1; #13),
#  "ShortRunHighGrayLevelEmphasis" (1; #14),
#  "ShortRunLowGrayLevelEmphasis" (1; #15)]

# %%
# Feature importance
model.make_inspector().variable_importances()
# Out:
# {'INV_MEAN_MIN_DEPTH': [("LongRunHighGrayLevelEmphasis" (1; #5),
#    0.16732217323753124),
#   ("HighGrayLevelRunEmphasis" (1; #3), 0.1624708641431998),
#   ("ShortRunLowGrayLevelEmphasis" (1; #15), 0.1482961720189153),
#   ("ShortRunHighGrayLevelEmphasis" (1; #14), 0.1304452046332334),
#   ("RunEntropy" (1; #8), 0.12469692143338758),
#   ("LowGrayLevelRunEmphasis" (1; #7), 0.12347225112379552),
#   ("GrayLevelNonUniformity" (1; #0), 0.11620004019374829),
#   ("LongRunLowGrayLevelEmphasis" (1; #6), 0.10446314261857852),
#   ("GrayLevelNonUniformityNormalized" (1; #1), 0.09367657567416215),
#   ("RunVariance" (1; #12), 0.0913834302530449),
#   ("GrayLevelVariance" (1; #2), 0.09003722524851157),
#   ("ShortRunEmphasis" (1; #13), 0.08821555764808592),
#   ("RunLengthNonUniformityNormalized" (1; #10), 0.0875973224457217),
#   ("LongRunEmphasis" (1; #4), 0.08551054044264166),
#   ("RunPercentage" (1; #11), 0.08487953675565248),
#   ("RunLengthNonUniformity" (1; #9), 0.08413712480836578)],
#  'NUM_AS_ROOT': [("ShortRunLowGrayLevelEmphasis" (1; #15), 80.0),
#   ("LowGrayLevelRunEmphasis" (1; #7), 63.0),
#   ("HighGrayLevelRunEmphasis" (1; #3), 60.0),
#   ("LongRunHighGrayLevelEmphasis" (1; #5), 34.0),
#   ("LongRunLowGrayLevelEmphasis" (1; #6), 34.0),
#   ("RunEntropy" (1; #8), 14.0),
#   ("GrayLevelNonUniformity" (1; #0), 7.0),
#   ("ShortRunHighGrayLevelEmphasis" (1; #14), 5.0),
#   ("GrayLevelNonUniformityNormalized" (1; #1), 1.0),
#   ("GrayLevelVariance" (1; #2), 1.0),
#   ("RunVariance" (1; #12), 1.0)],
#  'SUM_SCORE': [("HighGrayLevelRunEmphasis" (1; #3), 3425806.9141901345),
#   ("LongRunHighGrayLevelEmphasis" (1; #5), 3363956.719056445),
#   ("ShortRunLowGrayLevelEmphasis" (1; #15), 2895111.2528567268),
#   ("LowGrayLevelRunEmphasis" (1; #7), 2271802.2404504186),
#   ("ShortRunHighGrayLevelEmphasis" (1; #14), 2240922.4438265366),
#   ("RunEntropy" (1; #8), 2080319.2006856573),
#   ("GrayLevelNonUniformity" (1; #0), 1881097.2998456366),
#   ("LongRunLowGrayLevelEmphasis" (1; #6), 1503928.7197170723),
#   ("GrayLevelNonUniformityNormalized" (1; #1), 1060961.7823758414),
#   ("GrayLevelVariance" (1; #2), 1015843.8065327505),
#   ("RunVariance" (1; #12), 1002465.3140758763),
#   ("ShortRunEmphasis" (1; #13), 794381.242469175),
#   ("RunLengthNonUniformityNormalized" (1; #10), 783265.1109512215),
#   ("LongRunEmphasis" (1; #4), 738396.9630071631),
#   ("RunPercentage" (1; #11), 673246.7549462875),
#   ("RunLengthNonUniformity" (1; #9), 652749.0155397651)],
#  'NUM_NODES': [("GrayLevelNonUniformity" (1; #0), 40256.0),
#   ("RunEntropy" (1; #8), 40015.0),
#   ("LongRunHighGrayLevelEmphasis" (1; #5), 38901.0),
#   ("GrayLevelVariance" (1; #2), 37569.0),
#   ("GrayLevelNonUniformityNormalized" (1; #1), 34298.0),
#   ("ShortRunLowGrayLevelEmphasis" (1; #15), 33258.0),
#   ("ShortRunHighGrayLevelEmphasis" (1; #14), 32130.0),
#   ("HighGrayLevelRunEmphasis" (1; #3), 31698.0),
#   ("LongRunLowGrayLevelEmphasis" (1; #6), 31499.0),
#   ("LowGrayLevelRunEmphasis" (1; #7), 30960.0),
#   ("RunVariance" (1; #12), 30661.0),
#   ("RunLengthNonUniformityNormalized" (1; #10), 26795.0),
#   ("ShortRunEmphasis" (1; #13), 26737.0),
#   ("LongRunEmphasis" (1; #4), 25912.0),
#   ("RunLengthNonUniformity" (1; #9), 25037.0),
#   ("RunPercentage" (1; #11), 24108.0)]}

# %%
# Model self evaluation
model.make_inspector().evaluation()
# Out:
# Evaluation(num_examples=157612, accuracy=0.8568100038915867, loss=0.4660213632248924, rmse=None, ndcg=None, aucs=None, auuc=None, qini=None)

# %%
logs = model.make_inspector().training_logs()

plt.figure(figsize=(12, 4))
plt.subplot(1, 2, 1)
plt.plot([log.num_trees for log in logs], [log.evaluation.accuracy for log in logs])
plt.xlabel("Number of trees")
plt.ylabel("Accuracy (out-of-bag)")
plt.subplot(1, 2, 2)
plt.plot([log.num_trees for log in logs], [log.evaluation.loss for log in logs])
plt.xlabel("Number of trees")
plt.ylabel("Logloss (out-of-bag)")
plt.show()

# %% [markdown]
# Calculate the score of our hold-out validation dataset

# %%
predictions = model.predict(val_ds)
y_true      = validation_data["label"]

from sklearn.metrics import roc_auc_score
ROC_AUC = roc_auc_score(y_true, predictions)
print("The ROC AUC score is %.5f" % ROC_AUC )
# Out:
#  1/23 [>.............................] - ETA: 1s
#  3/23 [==>...........................] - ETA: 0s
#  5/23 [=====>........................] - ETA: 0s
#  7/23 [========>.....................] - ETA: 0s
#  9/23 [==========>...................] - ETA: 0s
# 11/23 [=============>................] - ETA: 0s
# 13/23 [===============>..............] - ETA: 0s
# 15/23 [==================>...........] - ETA: 0s
# 17/23 [=====================>........] - ETA: 0s
# 19/23 [=======================>......] - ETA: 0s
# 21/23 [==========================>...] - ETA: 0s
# 23/23 [==============================] - ETA: 0s
# 23/23 [==============================] - 1s 30ms/step
# The ROC AUC score is 0.94827

# %%
# Compute binary classification metrics with sklearn
import numpy as np
from sklearn.metrics import (
    accuracy_score,
    precision_score,
    recall_score,
    f1_score,
    roc_auc_score,
    average_precision_score,
    confusion_matrix,
    classification_report,
    matthews_corrcoef,
    log_loss,
    brier_score_loss,
)

# Get predictions (probabilities or class labels)
preds = model.predict(test_ds)
# If model outputs probabilities, convert to labels by threshold 0.5
if preds.ndim == 2:
    # For TFDF classification, preds may be class probabilities with shape (N, 2)
    if preds.shape[1] == 2:
        pos_probs = preds[:, 1]
    else:
        # If single-probability column (positive class)
        pos_probs = preds[:, -1]
    y_pred = (pos_probs >= 0.5).astype(int)
else:
    # Already class labels
    y_pred = preds.astype(int)
    pos_probs = None

# Ground truth labels (must be 0/1 integers)
y_true = test_data["label"].astype(int).to_numpy()

# Core metrics
metrics = {}
metrics["accuracy"] = accuracy_score(y_true, y_pred)
metrics["precision"] = precision_score(y_true, y_pred, zero_division=0)
metrics["recall"] = recall_score(y_true, y_pred, zero_division=0)
metrics["f1"] = f1_score(y_true, y_pred, zero_division=0)
metrics["mcc"] = matthews_corrcoef(y_true, y_pred)

# Probabilistic metrics (only if we have probabilities)
if pos_probs is not None:
    metrics["roc_auc"] = roc_auc_score(y_true, pos_probs)
    metrics["pr_auc"] = average_precision_score(y_true, pos_probs)
    metrics["log_loss"] = log_loss(y_true, pos_probs, labels=[0,1])
    metrics["brier_score"] = brier_score_loss(y_true, pos_probs)

# Confusion matrix and detailed report
cm = confusion_matrix(y_true, y_pred, labels=[0,1])
report = classification_report(y_true, y_pred, digits=4)

print("Sklearn binary metrics:")
for k, v in metrics.items():
    print(f"{k}: {v:.4f}")
print("\nConfusion matrix:\n", cm)
print("\nClassification report:\n", report)
# Out:
#  1/46 [..............................] - ETA: 4s
#  3/46 [>.............................] - ETA: 1s
#  5/46 [==>...........................] - ETA: 1s
#  7/46 [===>..........................] - ETA: 1s
#  9/46 [====>.........................] - ETA: 1s
# 11/46 [======>.......................] - ETA: 1s
# 13/46 [=======>......................] - ETA: 0s
# 15/46 [========>.....................] - ETA: 0s
# 17/46 [==========>...................] - ETA: 0s
# 19/46 [===========>..................] - ETA: 0s
# 21/46 [============>.................] - ETA: 0s
# 23/46 [==============>...............] - ETA: 0s
# 25/46 [===============>..............] - ETA: 0s
# 27/46 [================>.............] - ETA: 0s
# 29/46 [=================>............] - ETA: 0s
# 31/46 [===================>..........] - ETA: 0s
# 33/46 [====================>.........] - ETA: 0s
# 35/46 [=====================>........] - ETA: 0s
# 37/46 [=======================>......] - ETA: 0s
# 39/46 [========================>.....] - ETA: 0s
# 41/46 [=========================>....] - ETA: 0s
# 43/46 [===========================>..] - ETA: 0s
# 45/46 [============================>.] - ETA: 0s
# 46/46 [==============================] - 1s 30ms/step
# Sklearn binary metrics:
# accuracy: 0.9247
# precision: 0.4573
# recall: 0.7729
# f1: 0.5746
# mcc: 0.5586
# roc_auc: 0.9471
# pr_auc: 0.6853
# log_loss: 0.1870
# brier_score: 0.0557
#
# Confusion matrix:
#  [[39349  2719]
#  [  673  2291]]
#
# Classification report:
#                precision    recall  f1-score   support
#
#            0     0.9832    0.9354    0.9587     42068
#            1     0.4573    0.7729    0.5746      2964
#
#     accuracy                         0.9247     45032
#    macro avg     0.7202    0.8542    0.7666     45032
# weighted avg     0.9486    0.9247    0.9334     45032
