# %%
# Import packages and modules
import numpy  as np
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow_decision_forests as tfdf

from sklearn.model_selection import train_test_split
# Out:
# 2026-07-04 08:42:16.515728: I tensorflow/core/util/port.cc:113] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2026-07-04 08:42:16.564361: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2026-07-04 08:42:20.977518: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
# Check the version of TensorFlow Decision Forests
print("Found TensorFlow Decision Forests v" + tfdf.__version__)
# Out:
# Found TensorFlow Decision Forests v1.9.1

# %%
datasetPath = 'dataset/firstorder/kernel5-radius5/dataset.csv'

# %%
# Parameters
datasetPath = "dataset/gldm/kernel5-radius5/300.dataset.csv"

# %%
# train/validation/test = 70/10/20
dataset = pd.read_csv(datasetPath)

train_data, temp_data = train_test_split(dataset, test_size=0.3, random_state=42)
validation_data, test_data = train_test_split(temp_data, test_size=2/3, random_state=42)

# %%
from sklearn.utils.class_weight import compute_class_weight

# tinh class weight tren tap train
classes = np.array([0, 1])
weights = compute_class_weight(class_weight="balanced", classes=classes, y=train_data["label"])
class_weight = {0: weights[0], 1: weights[1]}

# gan sample_weight cho tung dong
train_data["sample_weight"] = train_data["label"].map(class_weight)
validation_data["sample_weight"] = validation_data["label"].map(class_weight)
test_data["sample_weight"] = test_data["label"].map(class_weight)

# Convert the dataset into a TensorFlow dataset.
train_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    train_data, label="label", weight="sample_weight"
)         
val_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    validation_data, label="label", weight="sample_weight"
)
test_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    test_data, label="label", weight="sample_weight"
)
# Out:
# 2026-07-04 08:42:33.283389: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:984] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2026-07-04 08:42:33.284958: W tensorflow/core/common_runtime/gpu/gpu_device.cc:2251] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...

# %%
import keras

# %%
# %%time

# Train a Random Forest model.
model = tfdf.keras.RandomForestModel()

# Add evaluation metrics
model.compile(
    metrics=["accuracy"]
)
model.fit(x=train_ds)

# # Train a Gradient Boosted Trees model.
# model = tfdf.keras.GradientBoostedTreesModel(num_trees=1500)
# model.fit(train_ds)
# Out:
# Use /tmp/tmpnnkrb4gp as temporary training directory
# Reading training dataset...
# Training dataset read in 0:00:03.283912. Found 235709 examples.
# Training model...
# [INFO 26-07-04 08:43:01.9913 UTC kernel.cc:1233] Loading model from path /tmp/tmpnnkrb4gp/model/ with prefix 904ea6098a6a4f04
# [INFO 26-07-04 08:43:03.5580 UTC decision_forest.cc:734] Model loaded with 300 root(s), 1335584 node(s), and 14 input feature(s).
# [INFO 26-07-04 08:43:03.5580 UTC abstract_model.cc:1362] Engine "RandomForestOptPred" built
# [INFO 26-07-04 08:43:03.5580 UTC kernel.cc:1061] Use fast generic engine
# Model trained in 0:00:27.052376
# Compiling model...
# Model compiled.
# CPU times: user 4min 48s, sys: 1.92 s, total: 4min 50s
# Wall time: 33.4 s

# %%
# Evaluate the model
evaluate = model.evaluate(val_ds, return_dict=True)
print()

for name, value in evaluate.items():
    print(f"{name}: {value:.4f}")
# Out:
# WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
#  1/34 [..............................] - ETA: 1:39 - loss: 0.0000e+00 - accuracy: 0.9400
#  3/34 [=>............................] - ETA: 0s - loss: 0.0000e+00 - accuracy: 0.9283
#  5/34 [===>..........................] - ETA: 0s - loss: 0.0000e+00 - accuracy: 0.9270
#  7/34 [=====>........................] - ETA: 0s - loss: 0.0000e+00 - accuracy: 0.9303
#  9/34 [======>.......................] - ETA: 0s - loss: 0.0000e+00 - accuracy: 0.9304
# 11/34 [========>.....................] - ETA: 0s - loss: 0.0000e+00 - accuracy: 0.9294
# 13/34 [==========>...................] - ETA: 0s - loss: 0.0000e+00 - accuracy: 0.9293
# 15/34 [============>.................] - ETA: 0s - loss: 0.0000e+00 - accuracy: 0.9300
# 17/34 [==============>...............] - ETA: 0s - loss: 0.0000e+00 - accuracy: 0.9308
# 19/34 [===============>..............] - ETA: 0s - loss: 0.0000e+00 - accuracy: 0.9309
# 21/34 [=================>............] - ETA: 0s - loss: 0.0000e+00 - accuracy: 0.9301
# 23/34 [===================>..........] - ETA: 0s - loss: 0.0000e+00 - accuracy: 0.9311
# 25/34 [=====================>........] - ETA: 0s - loss: 0.0000e+00 - accuracy: 0.9315
# 27/34 [======================>.......] - ETA: 0s - loss: 0.0000e+00 - accuracy: 0.9313
# 29/34 [========================>.....] - ETA: 0s - loss: 0.0000e+00 - accuracy: 0.9314
# 31/34 [==========================>...] - ETA: 0s - loss: 0.0000e+00 - accuracy: 0.9312
# 33/34 [============================>.] - ETA: 0s - loss: 0.0000e+00 - accuracy: 0.9314
# 34/34 [==============================] - 4s 32ms/step - loss: 0.0000e+00 - accuracy: 0.9313
# loss: 0.0000
# accuracy: 0.9313

# %%
# Model Summary
model.summary()
# Out:
# Model: "random_forest_model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
# =================================================================
# Total params: 1 (1.00 Byte)
# Trainable params: 0 (0.00 Byte)
# Non-trainable params: 1 (1.00 Byte)
# _________________________________________________________________
# Type: "RANDOM_FOREST"
# Task: CLASSIFICATION
# Label: "__LABEL"
#
# Input Features (14):
# 	DependenceEntropy
# 	DependenceNonUniformity
# 	DependenceNonUniformityNormalized
# 	DependenceVariance
# 	GrayLevelNonUniformity
# 	GrayLevelVariance
# 	HighGrayLevelEmphasis
# 	LargeDependenceEmphasis
# 	LargeDependenceHighGrayLevelEmphasis
# 	LargeDependenceLowGrayLevelEmphasis
# 	LowGrayLevelEmphasis
# 	SmallDependenceEmphasis
# 	SmallDependenceHighGrayLevelEmphasis
# 	SmallDependenceLowGrayLevelEmphasis
#
# Trained with weights
#
# Variable Importance: INV_MEAN_MIN_DEPTH:
#     1.                "HighGrayLevelEmphasis"  0.244372 ################
#     2.                    "DependenceEntropy"  0.154009 #######
#     3. "LargeDependenceHighGrayLevelEmphasis"  0.150205 ######
#     4.                 "LowGrayLevelEmphasis"  0.142018 ######
#     5.  "SmallDependenceLowGrayLevelEmphasis"  0.125937 ####
#     6. "SmallDependenceHighGrayLevelEmphasis"  0.123159 ####
#     7.  "LargeDependenceLowGrayLevelEmphasis"  0.111748 ###
#     8.               "GrayLevelNonUniformity"  0.110820 ###
#     9.              "SmallDependenceEmphasis"  0.103125 ##
#    10.                    "GrayLevelVariance"  0.096050 #
#    11.                   "DependenceVariance"  0.082371
#    12.              "LargeDependenceEmphasis"  0.081582
#    13.    "DependenceNonUniformityNormalized"  0.079197
#    14.              "DependenceNonUniformity"  0.079050
#
# Variable Importance: NUM_AS_ROOT:
#     1.                "HighGrayLevelEmphasis" 95.000000 ################
#     2.                 "LowGrayLevelEmphasis" 78.000000 #############
#     3.  "LargeDependenceLowGrayLevelEmphasis" 53.000000 ########
#     4. "LargeDependenceHighGrayLevelEmphasis" 32.000000 ####
#     5.  "SmallDependenceLowGrayLevelEmphasis" 19.000000 ##
#     6. "SmallDependenceHighGrayLevelEmphasis" 12.000000 #
#     7.                    "DependenceEntropy"  7.000000
#     8.               "GrayLevelNonUniformity"  4.000000
#
# Variable Importance: NUM_NODES:
#     1.                    "DependenceEntropy" 58771.000000 ################
#     2. "LargeDependenceHighGrayLevelEmphasis" 57770.000000 ###############
#     3.               "GrayLevelNonUniformity" 56668.000000 ##############
#     4.  "SmallDependenceLowGrayLevelEmphasis" 54639.000000 #############
#     5. "SmallDependenceHighGrayLevelEmphasis" 51949.000000 ###########
#     6.                    "GrayLevelVariance" 51408.000000 ###########
#     7.              "SmallDependenceEmphasis" 51399.000000 ###########
#     8.                "HighGrayLevelEmphasis" 49965.000000 ##########
#     9.                 "LowGrayLevelEmphasis" 45029.000000 #######
#    10.  "LargeDependenceLowGrayLevelEmphasis" 43354.000000 ######
#    11.                   "DependenceVariance" 40992.000000 ####
#    12.              "LargeDependenceEmphasis" 37912.000000 ##
#    13.              "DependenceNonUniformity" 33951.000000
#    14.    "DependenceNonUniformityNormalized" 33835.000000
#
# Variable Importance: SUM_SCORE:
#     1.                "HighGrayLevelEmphasis" 8457103.687910 ################
#     2.                    "DependenceEntropy" 4547389.341175 #######
#     3.                 "LowGrayLevelEmphasis" 4484996.992951 #######
#     4. "LargeDependenceHighGrayLevelEmphasis" 4128333.535197 #######
#     5.  "SmallDependenceLowGrayLevelEmphasis" 3190428.756629 #####
#     6. "SmallDependenceHighGrayLevelEmphasis" 2998466.078250 ####
#     7.  "LargeDependenceLowGrayLevelEmphasis" 2934187.974858 ####
#     8.               "GrayLevelNonUniformity" 2575722.637481 ###
#     9.              "SmallDependenceEmphasis" 2115595.824846 ##
#    10.                    "GrayLevelVariance" 1778585.373868 ##
#    11.                   "DependenceVariance" 905272.238098
#    12.              "LargeDependenceEmphasis" 895587.812224
#    13.    "DependenceNonUniformityNormalized" 701265.518610
#    14.              "DependenceNonUniformity" 692748.412758
#
#
#
# Winner takes all: true
# Out-of-bag evaluation: accuracy:0.868112 logloss:0.444976
# Number of trees: 300
# Total number of nodes: 1335584
#
# Number of nodes by tree:
# Count: 300 Average: 4451.95 StdDev: 266.588
# Min: 3643 Max: 5229 Ignored: 0
# ----------------------------------------------
# [ 3643, 3722)  2   0.67%   0.67% #
# [ 3722, 3801)  0   0.00%   0.67%
# [ 3801, 3881)  0   0.00%   0.67%
# [ 3881, 3960)  2   0.67%   1.33% #
# [ 3960, 4039)  9   3.00%   4.33% ##
# [ 4039, 4119) 18   6.00%  10.33% #####
# [ 4119, 4198) 25   8.33%  18.67% #######
# [ 4198, 4277) 20   6.67%  25.33% #####
# [ 4277, 4357) 36  12.00%  37.33% #########
# [ 4357, 4436) 37  12.33%  49.67% ##########
# [ 4436, 4515) 38  12.67%  62.33% ##########
# [ 4515, 4595) 27   9.00%  71.33% #######
# [ 4595, 4674) 25   8.33%  79.67% #######
# [ 4674, 4753) 19   6.33%  86.00% #####
# [ 4753, 4833) 19   6.33%  92.33% #####
# [ 4833, 4912)  9   3.00%  95.33% ##
# [ 4912, 4991)  4   1.33%  96.67% #
# [ 4991, 5071)  5   1.67%  98.33% #
# [ 5071, 5150)  2   0.67%  99.00% #
# [ 5150, 5229]  3   1.00% 100.00% #
#
# Depth by leafs:
# Count: 667942 Average: 12.9958 StdDev: 2.02675
# Min: 3 Max: 15 Ignored: 0
# ----------------------------------------------
# [  3,  4)      1   0.00%   0.00%
# [  4,  5)     37   0.01%   0.01%
# [  5,  6)    358   0.05%   0.06%
# [  6,  7)   1706   0.26%   0.31%
# [  7,  8)   5202   0.78%   1.09%
# [  8,  9)  12656   1.89%   2.99% #
# [  9, 10)  25390   3.80%   6.79% #
# [ 10, 11)  43681   6.54%  13.33% ##
# [ 11, 12)  63935   9.57%  22.90% ###
# [ 12, 13)  83788  12.54%  35.45% ####
# [ 13, 14) 100308  15.02%  50.46% #####
# [ 14, 15) 110656  16.57%  67.03% #####
# [ 15, 15] 220224  32.97% 100.00% ##########
#
# Number of training obs by leaf:
# Count: 667942 Average: 105.867 StdDev: 624.609
# Min: 5 Max: 28955 Ignored: 0
# ----------------------------------------------
# [     5,  1452) 660284  98.85%  98.85% ##########
# [  1452,  2900)   4127   0.62%  99.47%
# [  2900,  4347)   1457   0.22%  99.69%
# [  4347,  5795)    721   0.11%  99.80%
# [  5795,  7242)    356   0.05%  99.85%
# [  7242,  8690)    232   0.03%  99.89%
# [  8690, 10137)    159   0.02%  99.91%
# [ 10137, 11585)    124   0.02%  99.93%
# [ 11585, 13032)    115   0.02%  99.95%
# [ 13032, 14480)     81   0.01%  99.96%
# [ 14480, 15928)     55   0.01%  99.97%
# [ 15928, 17375)     59   0.01%  99.97%
# [ 17375, 18823)     42   0.01%  99.98%
# [ 18823, 20270)     39   0.01%  99.99%
# [ 20270, 21718)     26   0.00%  99.99%
# [ 21718, 23165)     24   0.00%  99.99%
# [ 23165, 24613)     15   0.00% 100.00%
# [ 24613, 26060)     14   0.00% 100.00%
# [ 26060, 27508)      6   0.00% 100.00%
# [ 27508, 28955]      6   0.00% 100.00%
#
# Attribute in nodes:
# 	58771 : DependenceEntropy [NUMERICAL]
# 	57770 : LargeDependenceHighGrayLevelEmphasis [NUMERICAL]
# 	56668 : GrayLevelNonUniformity [NUMERICAL]
# 	54639 : SmallDependenceLowGrayLevelEmphasis [NUMERICAL]
# 	51949 : SmallDependenceHighGrayLevelEmphasis [NUMERICAL]
# 	51408 : GrayLevelVariance [NUMERICAL]
# 	51399 : SmallDependenceEmphasis [NUMERICAL]
# 	49965 : HighGrayLevelEmphasis [NUMERICAL]
# 	45029 : LowGrayLevelEmphasis [NUMERICAL]
# 	43354 : LargeDependenceLowGrayLevelEmphasis [NUMERICAL]
# 	40992 : DependenceVariance [NUMERICAL]
# 	37912 : LargeDependenceEmphasis [NUMERICAL]
# 	33951 : DependenceNonUniformity [NUMERICAL]
# 	33835 : DependenceNonUniformityNormalized [NUMERICAL]
#
# Attribute in nodes with depth <= 0:
# 	95 : HighGrayLevelEmphasis [NUMERICAL]
# 	78 : LowGrayLevelEmphasis [NUMERICAL]
# 	53 : LargeDependenceLowGrayLevelEmphasis [NUMERICAL]
# 	32 : LargeDependenceHighGrayLevelEmphasis [NUMERICAL]
# 	19 : SmallDependenceLowGrayLevelEmphasis [NUMERICAL]
# 	12 : SmallDependenceHighGrayLevelEmphasis [NUMERICAL]
# 	7 : DependenceEntropy [NUMERICAL]
# 	4 : GrayLevelNonUniformity [NUMERICAL]
#
# Attribute in nodes with depth <= 1:
# 	278 : HighGrayLevelEmphasis [NUMERICAL]
# 	161 : LargeDependenceHighGrayLevelEmphasis [NUMERICAL]
# 	138 : LowGrayLevelEmphasis [NUMERICAL]
# 	73 : LargeDependenceLowGrayLevelEmphasis [NUMERICAL]
# 	70 : SmallDependenceLowGrayLevelEmphasis [NUMERICAL]
# 	69 : DependenceEntropy [NUMERICAL]
# 	43 : SmallDependenceHighGrayLevelEmphasis [NUMERICAL]
# 	35 : GrayLevelNonUniformity [NUMERICAL]
# 	14 : GrayLevelVariance [NUMERICAL]
# 	13 : SmallDependenceEmphasis [NUMERICAL]
# 	3 : LargeDependenceEmphasis [NUMERICAL]
# 	3 : DependenceVariance [NUMERICAL]
#
# Attribute in nodes with depth <= 2:
# 	563 : HighGrayLevelEmphasis [NUMERICAL]
# 	318 : LargeDependenceHighGrayLevelEmphasis [NUMERICAL]
# 	228 : LowGrayLevelEmphasis [NUMERICAL]
# 	192 : SmallDependenceHighGrayLevelEmphasis [NUMERICAL]
# 	187 : DependenceEntropy [NUMERICAL]
# 	177 : SmallDependenceLowGrayLevelEmphasis [NUMERICAL]
# 	134 : LargeDependenceLowGrayLevelEmphasis [NUMERICAL]
# 	100 : GrayLevelNonUniformity [NUMERICAL]
# 	80 : SmallDependenceEmphasis [NUMERICAL]
# 	46 : GrayLevelVariance [NUMERICAL]
# 	28 : DependenceVariance [NUMERICAL]
# 	27 : LargeDependenceEmphasis [NUMERICAL]
# 	13 : DependenceNonUniformityNormalized [NUMERICAL]
# 	7 : DependenceNonUniformity [NUMERICAL]
#
# Attribute in nodes with depth <= 3:
# 	977 : HighGrayLevelEmphasis [NUMERICAL]
# 	615 : LargeDependenceHighGrayLevelEmphasis [NUMERICAL]
# 	574 : DependenceEntropy [NUMERICAL]
# 	416 : SmallDependenceLowGrayLevelEmphasis [NUMERICAL]
# 	404 : LowGrayLevelEmphasis [NUMERICAL]
# 	352 : SmallDependenceHighGrayLevelEmphasis [NUMERICAL]
# 	283 : GrayLevelNonUniformity [NUMERICAL]
# 	269 : SmallDependenceEmphasis [NUMERICAL]
# 	204 : LargeDependenceLowGrayLevelEmphasis [NUMERICAL]
# 	187 : GrayLevelVariance [NUMERICAL]
# 	84 : DependenceVariance [NUMERICAL]
# 	57 : LargeDependenceEmphasis [NUMERICAL]
# 	40 : DependenceNonUniformity [NUMERICAL]
# 	37 : DependenceNonUniformityNormalized [NUMERICAL]
#
# Attribute in nodes with depth <= 5:
# 	2606 : HighGrayLevelEmphasis [NUMERICAL]
# 	2561 : DependenceEntropy [NUMERICAL]
# 	2376 : LargeDependenceHighGrayLevelEmphasis [NUMERICAL]
# 	1636 : SmallDependenceLowGrayLevelEmphasis [NUMERICAL]
# 	1550 : GrayLevelNonUniformity [NUMERICAL]
# 	1517 : SmallDependenceEmphasis [NUMERICAL]
# 	1296 : LowGrayLevelEmphasis [NUMERICAL]
# 	1290 : SmallDependenceHighGrayLevelEmphasis [NUMERICAL]
# 	1195 : GrayLevelVariance [NUMERICAL]
# 	749 : LargeDependenceLowGrayLevelEmphasis [NUMERICAL]
# 	478 : LargeDependenceEmphasis [NUMERICAL]
# 	476 : DependenceVariance [NUMERICAL]
# 	351 : DependenceNonUniformity [NUMERICAL]
# 	343 : DependenceNonUniformityNormalized [NUMERICAL]
#
# Condition type in nodes:
# 	667642 : HigherCondition
# Condition type in nodes with depth <= 0:
# 	300 : HigherCondition
# Condition type in nodes with depth <= 1:
# 	900 : HigherCondition
# Condition type in nodes with depth <= 2:
# 	2100 : HigherCondition
# Condition type in nodes with depth <= 3:
# 	4499 : HigherCondition
# Condition type in nodes with depth <= 5:
# 	18424 : HigherCondition
# Node format: NOT_SET
#
# Training OOB:
# 	trees: 1, Out-of-bag evaluation: accuracy:0.840712 logloss:5.74132
# 	trees: 11, Out-of-bag evaluation: accuracy:0.844974 logloss:2.39212
# 	trees: 21, Out-of-bag evaluation: accuracy:0.855534 logloss:1.46885
# 	trees: 31, Out-of-bag evaluation: accuracy:0.85985 logloss:1.10339
# 	trees: 41, Out-of-bag evaluation: accuracy:0.860524 logloss:0.950671
# 	trees: 51, Out-of-bag evaluation: accuracy:0.863515 logloss:0.842216
# 	trees: 61, Out-of-bag evaluation: accuracy:0.865526 logloss:0.767284
# 	trees: 71, Out-of-bag evaluation: accuracy:0.866339 logloss:0.71301
# 	trees: 81, Out-of-bag evaluation: accuracy:0.86603 logloss:0.679933
# 	trees: 91, Out-of-bag evaluation: accuracy:0.866395 logloss:0.644838
# 	trees: 101, Out-of-bag evaluation: accuracy:0.8664 logloss:0.623804
# 	trees: 111, Out-of-bag evaluation: accuracy:0.866281 logloss:0.595472
# 	trees: 121, Out-of-bag evaluation: accuracy:0.86676 logloss:0.569625
# 	trees: 131, Out-of-bag evaluation: accuracy:0.867311 logloss:0.554703
# 	trees: 141, Out-of-bag evaluation: accuracy:0.867573 logloss:0.539004
# 	trees: 151, Out-of-bag evaluation: accuracy:0.867423 logloss:0.526987
# 	trees: 161, Out-of-bag evaluation: accuracy:0.867596 logloss:0.518115
# 	trees: 171, Out-of-bag evaluation: accuracy:0.86735 logloss:0.509224
# 	trees: 181, Out-of-bag evaluation: accuracy:0.867343 logloss:0.504608
# 	trees: 191, Out-of-bag evaluation: accuracy:0.867141 logloss:0.49479
# 	trees: 201, Out-of-bag evaluation: accuracy:0.867383 logloss:0.486272
# 	trees: 211, Out-of-bag evaluation: accuracy:0.867376 logloss:0.479667
# 	trees: 221, Out-of-bag evaluation: accuracy:0.86736 logloss:0.472266
# 	trees: 231, Out-of-bag evaluation: accuracy:0.867769 logloss:0.468782
# 	trees: 241, Out-of-bag evaluation: accuracy:0.868015 logloss:0.466256
# 	trees: 251, Out-of-bag evaluation: accuracy:0.868118 logloss:0.462696
# 	trees: 261, Out-of-bag evaluation: accuracy:0.867849 logloss:0.453344
# 	trees: 271, Out-of-bag evaluation: accuracy:0.868024 logloss:0.448781
# 	trees: 281, Out-of-bag evaluation: accuracy:0.867822 logloss:0.448437
# 	trees: 291, Out-of-bag evaluation: accuracy:0.867893 logloss:0.446262
# 	trees: 300, Out-of-bag evaluation: accuracy:0.868112 logloss:0.444976

# %%
# Model features
model.make_inspector().features()
# Out:
# ["DependenceEntropy" (1; #0),
#  "DependenceNonUniformity" (1; #1),
#  "DependenceNonUniformityNormalized" (1; #2),
#  "DependenceVariance" (1; #3),
#  "GrayLevelNonUniformity" (1; #4),
#  "GrayLevelVariance" (1; #5),
#  "HighGrayLevelEmphasis" (1; #6),
#  "LargeDependenceEmphasis" (1; #7),
#  "LargeDependenceHighGrayLevelEmphasis" (1; #8),
#  "LargeDependenceLowGrayLevelEmphasis" (1; #9),
#  "LowGrayLevelEmphasis" (1; #10),
#  "SmallDependenceEmphasis" (1; #11),
#  "SmallDependenceHighGrayLevelEmphasis" (1; #12),
#  "SmallDependenceLowGrayLevelEmphasis" (1; #13)]

# %%
# Feature importance
model.make_inspector().variable_importances()
# Out:
# {'INV_MEAN_MIN_DEPTH': [("HighGrayLevelEmphasis" (1; #6), 0.24437190636152098),
#   ("DependenceEntropy" (1; #0), 0.15400947268615187),
#   ("LargeDependenceHighGrayLevelEmphasis" (1; #8), 0.15020546363503512),
#   ("LowGrayLevelEmphasis" (1; #10), 0.1420177540725193),
#   ("SmallDependenceLowGrayLevelEmphasis" (1; #13), 0.12593673810258577),
#   ("SmallDependenceHighGrayLevelEmphasis" (1; #12), 0.12315946857875545),
#   ("LargeDependenceLowGrayLevelEmphasis" (1; #9), 0.11174807011663512),
#   ("GrayLevelNonUniformity" (1; #4), 0.11081992077417523),
#   ("SmallDependenceEmphasis" (1; #11), 0.10312539874573733),
#   ("GrayLevelVariance" (1; #5), 0.09604977619462243),
#   ("DependenceVariance" (1; #3), 0.08237056056247476),
#   ("LargeDependenceEmphasis" (1; #7), 0.0815815469363021),
#   ("DependenceNonUniformityNormalized" (1; #2), 0.07919651348216084),
#   ("DependenceNonUniformity" (1; #1), 0.07905013548508849)],
#  'SUM_SCORE': [("HighGrayLevelEmphasis" (1; #6), 8457103.687910203),
#   ("DependenceEntropy" (1; #0), 4547389.341175153),
#   ("LowGrayLevelEmphasis" (1; #10), 4484996.992951121),
#   ("LargeDependenceHighGrayLevelEmphasis" (1; #8), 4128333.5351967514),
#   ("SmallDependenceLowGrayLevelEmphasis" (1; #13), 3190428.756628794),
#   ("SmallDependenceHighGrayLevelEmphasis" (1; #12), 2998466.0782501823),
#   ("LargeDependenceLowGrayLevelEmphasis" (1; #9), 2934187.974857838),
#   ("GrayLevelNonUniformity" (1; #4), 2575722.63748107),
#   ("SmallDependenceEmphasis" (1; #11), 2115595.82484601),
#   ("GrayLevelVariance" (1; #5), 1778585.3738684666),
#   ("DependenceVariance" (1; #3), 905272.2380984243),
#   ("LargeDependenceEmphasis" (1; #7), 895587.8122240201),
#   ("DependenceNonUniformityNormalized" (1; #2), 701265.5186096019),
#   ("DependenceNonUniformity" (1; #1), 692748.412757837)],
#  'NUM_AS_ROOT': [("HighGrayLevelEmphasis" (1; #6), 95.0),
#   ("LowGrayLevelEmphasis" (1; #10), 78.0),
#   ("LargeDependenceLowGrayLevelEmphasis" (1; #9), 53.0),
#   ("LargeDependenceHighGrayLevelEmphasis" (1; #8), 32.0),
#   ("SmallDependenceLowGrayLevelEmphasis" (1; #13), 19.0),
#   ("SmallDependenceHighGrayLevelEmphasis" (1; #12), 12.0),
#   ("DependenceEntropy" (1; #0), 7.0),
#   ("GrayLevelNonUniformity" (1; #4), 4.0)],
#  'NUM_NODES': [("DependenceEntropy" (1; #0), 58771.0),
#   ("LargeDependenceHighGrayLevelEmphasis" (1; #8), 57770.0),
#   ("GrayLevelNonUniformity" (1; #4), 56668.0),
#   ("SmallDependenceLowGrayLevelEmphasis" (1; #13), 54639.0),
#   ("SmallDependenceHighGrayLevelEmphasis" (1; #12), 51949.0),
#   ("GrayLevelVariance" (1; #5), 51408.0),
#   ("SmallDependenceEmphasis" (1; #11), 51399.0),
#   ("HighGrayLevelEmphasis" (1; #6), 49965.0),
#   ("LowGrayLevelEmphasis" (1; #10), 45029.0),
#   ("LargeDependenceLowGrayLevelEmphasis" (1; #9), 43354.0),
#   ("DependenceVariance" (1; #3), 40992.0),
#   ("LargeDependenceEmphasis" (1; #7), 37912.0),
#   ("DependenceNonUniformity" (1; #1), 33951.0),
#   ("DependenceNonUniformityNormalized" (1; #2), 33835.0)]}

# %%
# Model self evaluation
model.make_inspector().evaluation()
# Out:
# Evaluation(num_examples=235709, accuracy=0.8681120991123507, loss=0.4449755733244557, rmse=None, ndcg=None, aucs=None, auuc=None, qini=None)

# %%
logs = model.make_inspector().training_logs()

plt.figure(figsize=(12, 4))
plt.subplot(1, 2, 1)
plt.plot([log.num_trees for log in logs], [log.evaluation.accuracy for log in logs])
plt.xlabel("Number of trees")
plt.ylabel("Accuracy (out-of-bag)")
plt.subplot(1, 2, 2)
plt.plot([log.num_trees for log in logs], [log.evaluation.loss for log in logs])
plt.xlabel("Number of trees")
plt.ylabel("Logloss (out-of-bag)")
plt.show()

# %% [markdown]
# Calculate the score of our hold-out validation dataset

# %%
predictions = model.predict(val_ds)
y_true      = validation_data["label"]

from sklearn.metrics import roc_auc_score
ROC_AUC = roc_auc_score(y_true, predictions)
print("The ROC AUC score is %.5f" % ROC_AUC )
# Out:
#  1/34 [..............................] - ETA: 2s
#  3/34 [=>............................] - ETA: 0s
#  5/34 [===>..........................] - ETA: 0s
#  7/34 [=====>........................] - ETA: 0s
#  9/34 [======>.......................] - ETA: 0s
# 11/34 [========>.....................] - ETA: 0s
# 13/34 [==========>...................] - ETA: 0s
# 15/34 [============>.................] - ETA: 0s
# 17/34 [==============>...............] - ETA: 0s
# 19/34 [===============>..............] - ETA: 0s
# 21/34 [=================>............] - ETA: 0s
# 23/34 [===================>..........] - ETA: 0s
# 25/34 [=====================>........] - ETA: 0s
# 27/34 [======================>.......] - ETA: 0s
# 29/34 [========================>.....] - ETA: 0s
# 31/34 [==========================>...] - ETA: 0s
# 33/34 [============================>.] - ETA: 0s
# 34/34 [==============================] - 1s 31ms/step
# The ROC AUC score is 0.95902

# %%
# Compute binary classification metrics with sklearn
import numpy as np
from sklearn.metrics import (
    accuracy_score,
    precision_score,
    recall_score,
    f1_score,
    roc_auc_score,
    average_precision_score,
    confusion_matrix,
    classification_report,
    matthews_corrcoef,
    log_loss,
    brier_score_loss,
)

# Get predictions (probabilities or class labels)
preds = model.predict(test_ds)
# If model outputs probabilities, convert to labels by threshold 0.5
if preds.ndim == 2:
    # For TFDF classification, preds may be class probabilities with shape (N, 2)
    if preds.shape[1] == 2:
        pos_probs = preds[:, 1]
    else:
        # If single-probability column (positive class)
        pos_probs = preds[:, -1]
    y_pred = (pos_probs >= 0.5).astype(int)
else:
    # Already class labels
    y_pred = preds.astype(int)
    pos_probs = None

# Ground truth labels (must be 0/1 integers)
y_true = test_data["label"].astype(int).to_numpy()

# Core metrics
metrics = {}
metrics["accuracy"] = accuracy_score(y_true, y_pred)
metrics["precision"] = precision_score(y_true, y_pred, zero_division=0)
metrics["recall"] = recall_score(y_true, y_pred, zero_division=0)
metrics["f1"] = f1_score(y_true, y_pred, zero_division=0)
metrics["mcc"] = matthews_corrcoef(y_true, y_pred)

# Probabilistic metrics (only if we have probabilities)
if pos_probs is not None:
    metrics["roc_auc"] = roc_auc_score(y_true, pos_probs)
    metrics["pr_auc"] = average_precision_score(y_true, pos_probs)
    metrics["log_loss"] = log_loss(y_true, pos_probs, labels=[0,1])
    metrics["brier_score"] = brier_score_loss(y_true, pos_probs)

# Confusion matrix and detailed report
cm = confusion_matrix(y_true, y_pred, labels=[0,1])
report = classification_report(y_true, y_pred, digits=4)

print("Sklearn binary metrics:")
for k, v in metrics.items():
    print(f"{k}: {v:.4f}")
print("\nConfusion matrix:\n", cm)
print("\nClassification report:\n", report)
# Out:
#  1/68 [..............................] - ETA: 6s
#  3/68 [>.............................] - ETA: 2s
#  5/68 [=>............................] - ETA: 2s
#  7/68 [==>...........................] - ETA: 1s
#  8/68 [==>...........................] - ETA: 7s
# 10/68 [===>..........................] - ETA: 6s
# 12/68 [====>.........................] - ETA: 5s
# 14/68 [=====>........................] - ETA: 4s
# 15/68 [=====>........................] - ETA: 7s
# 17/68 [======>.......................] - ETA: 6s
# 19/68 [=======>......................] - ETA: 5s
# 21/68 [========>.....................] - ETA: 5s
# 23/68 [=========>....................] - ETA: 4s
# 25/68 [==========>...................] - ETA: 4s
# 27/68 [==========>...................] - ETA: 3s
# 29/68 [===========>..................] - ETA: 3s
# 31/68 [============>.................] - ETA: 3s
# 33/68 [=============>................] - ETA: 2s
# 35/68 [==============>...............] - ETA: 2s
# 37/68 [===============>..............] - ETA: 2s
# 39/68 [================>.............] - ETA: 2s
# 41/68 [=================>............] - ETA: 1s
# 43/68 [=================>............] - ETA: 1s
# 45/68 [==================>...........] - ETA: 1s
# 47/68 [===================>..........] - ETA: 1s
# 49/68 [====================>.........] - ETA: 1s
# 51/68 [=====================>........] - ETA: 1s
# 53/68 [======================>.......] - ETA: 0s
# 55/68 [=======================>......] - ETA: 0s
# 57/68 [========================>.....] - ETA: 0s
# 59/68 [=========================>....] - ETA: 0s
# 61/68 [=========================>....] - ETA: 0s
# 63/68 [==========================>...] - ETA: 0s
# 65/68 [===========================>..] - ETA: 0s
# 67/68 [============================>.] - ETA: 0s
# 68/68 [==============================] - 4s 55ms/step
# Sklearn binary metrics:
# accuracy: 0.9295
# precision: 0.4553
# recall: 0.7990
# f1: 0.5801
# mcc: 0.5705
# roc_auc: 0.9554
# pr_auc: 0.6687
# log_loss: 0.1794
# brier_score: 0.0524
#
# Confusion matrix:
#  [[59317  3924]
#  [  825  3280]]
#
# Classification report:
#                precision    recall  f1-score   support
#
#            0     0.9863    0.9380    0.9615     63241
#            1     0.4553    0.7990    0.5801      4105
#
#     accuracy                         0.9295     67346
#    macro avg     0.7208    0.8685    0.7708     67346
# weighted avg     0.9539    0.9295    0.9383     67346
