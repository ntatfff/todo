# %%
# Import packages and modules
import numpy  as np
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow_decision_forests as tfdf

from sklearn.model_selection import train_test_split
# Out:
# 2026-07-04 07:40:15.875620: I tensorflow/core/util/port.cc:113] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2026-07-04 07:40:15.915166: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2026-07-04 07:40:20.362574: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
# Check the version of TensorFlow Decision Forests
print("Found TensorFlow Decision Forests v" + tfdf.__version__)
# Out:
# Found TensorFlow Decision Forests v1.9.1

# %%
datasetPath = 'dataset/firstorder/kernel5-radius5/dataset.csv'

# %%
# Parameters
datasetPath = "dataset/firstorder/kernel5-radius5/500.dataset.csv"

# %%
# train/validation/test = 70/10/20
dataset = pd.read_csv(datasetPath)

train_data, temp_data = train_test_split(dataset, test_size=0.3, random_state=42)
validation_data, test_data = train_test_split(temp_data, test_size=2/3, random_state=42)

# %%
from sklearn.utils.class_weight import compute_class_weight

# tinh class weight tren tap train
classes = np.array([0, 1])
weights = compute_class_weight(class_weight="balanced", classes=classes, y=train_data["label"])
class_weight = {0: weights[0], 1: weights[1]}

# gan sample_weight cho tung dong
train_data["sample_weight"] = train_data["label"].map(class_weight)
validation_data["sample_weight"] = validation_data["label"].map(class_weight)
test_data["sample_weight"] = test_data["label"].map(class_weight)

# Convert the dataset into a TensorFlow dataset.
train_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    train_data, label="label", weight="sample_weight"
)         
val_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    validation_data, label="label", weight="sample_weight"
)
test_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    test_data, label="label", weight="sample_weight"
)
# Out:
# 2026-07-04 07:40:34.531288: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:984] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2026-07-04 07:40:34.533192: W tensorflow/core/common_runtime/gpu/gpu_device.cc:2251] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...

# %%
import keras

# %%
# %%time

# Train a Gradient Boosted Trees model.
model = tfdf.keras.GradientBoostedTreesModel()

# Add evaluation metrics
model.compile(
    metrics=["accuracy"]
)
model.fit(x=train_ds)

# # Train a Gradient Boosted Trees model.
# model = tfdf.keras.GradientBoostedTreesModel(num_trees=1500)
# model.fit(train_ds)
# Out:
# Use /tmp/tmp6dhoa4pz as temporary training directory
# [WARNING 26-07-04 07:40:34.7375 UTC gradient_boosted_trees.cc:1840] "goss_alpha" set but "sampling_method" not equal to "GOSS".
# [WARNING 26-07-04 07:40:34.7375 UTC gradient_boosted_trees.cc:1851] "goss_beta" set but "sampling_method" not equal to "GOSS".
# [WARNING 26-07-04 07:40:34.7375 UTC gradient_boosted_trees.cc:1865] "selective_gradient_boosting_ratio" set but "sampling_method" not equal to "SELGB".
# Reading training dataset...
# Training dataset read in 0:00:04.310101. Found 395895 examples.
# Training model...
# Model trained in 0:01:43.673404
# Compiling model...
# [INFO 26-07-04 07:42:22.7250 UTC kernel.cc:1233] Loading model from path /tmp/tmp6dhoa4pz/model/ with prefix 78b0a55554d641e5
# [INFO 26-07-04 07:42:22.7420 UTC quick_scorer_extended.cc:911] The binary was compiled without AVX2 support, but your CPU supports it. Enable it for faster model inference.
# [INFO 26-07-04 07:42:22.7433 UTC abstract_model.cc:1362] Engine "GradientBoostedTreesQuickScorerExtended" built
# [INFO 26-07-04 07:42:22.7434 UTC kernel.cc:1061] Use fast generic engine
# Model compiled.
# CPU times: user 13min 47s, sys: 5.18 s, total: 13min 52s
# Wall time: 1min 51s

# %%
# Evaluate the model
evaluate = model.evaluate(val_ds, return_dict=True)
print()

for name, value in evaluate.items():
    print(f"{name}: {value:.4f}")
# Out:
# WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
#  1/57 [..............................] - ETA: 2:47 - loss: 0.0000e+00 - accuracy: 0.8680
# 10/57 [====>.........................] - ETA: 0s - loss: 0.0000e+00 - accuracy: 0.8667
# 20/57 [=========>....................] - ETA: 0s - loss: 0.0000e+00 - accuracy: 0.8655
# 31/57 [===============>..............] - ETA: 0s - loss: 0.0000e+00 - accuracy: 0.8659
# 42/57 [=====================>........] - ETA: 0s - loss: 0.0000e+00 - accuracy: 0.8656
# 53/57 [==========================>...] - ETA: 0s - loss: 0.0000e+00 - accuracy: 0.8658
# 57/57 [==============================] - 3s 5ms/step - loss: 0.0000e+00 - accuracy: 0.8659
# loss: 0.0000
# accuracy: 0.8659

# %%
# Model Summary
model.summary()
# Out:
# Model: "gradient_boosted_trees_model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
# =================================================================
# Total params: 1 (1.00 Byte)
# Trainable params: 0 (0.00 Byte)
# Non-trainable params: 1 (1.00 Byte)
# _________________________________________________________________
# Type: "GRADIENT_BOOSTED_TREES"
# Task: CLASSIFICATION
# Label: "__LABEL"
#
# Input Features (18):
# 	10Percentile
# 	90Percentile
# 	Energy
# 	Entropy
# 	InterquartileRange
# 	Kurtosis
# 	Maximum
# 	Mean
# 	MeanAbsoluteDeviation
# 	Median
# 	Minimum
# 	Range
# 	RobustMeanAbsoluteDeviation
# 	RootMeanSquared
# 	Skewness
# 	TotalEnergy
# 	Uniformity
# 	Variance
#
# Trained with weights
#
# Variable Importance: INV_MEAN_MIN_DEPTH:
#     1.                    "Skewness"  0.224424 ################
#     2.                       "Range"  0.212021 ############
#     3.                     "Minimum"  0.210184 ###########
#     4.                "90Percentile"  0.208448 ###########
#     5.                    "Kurtosis"  0.207381 ##########
#     6.                     "Maximum"  0.200333 ########
#     7.                      "Median"  0.199225 ########
#     8.                "10Percentile"  0.197632 #######
#     9.                    "Variance"  0.191320 #####
#    10.                  "Uniformity"  0.190588 #####
#    11. "RobustMeanAbsoluteDeviation"  0.183971 ###
#    12.                        "Mean"  0.182350 ###
#    13.                     "Entropy"  0.180096 ##
#    14.       "MeanAbsoluteDeviation"  0.179249 ##
#    15.          "InterquartileRange"  0.178429 #
#    16.             "RootMeanSquared"  0.174652
#    17.                      "Energy"  0.173468
#    18.                 "TotalEnergy"  0.172361
#
# Variable Importance: NUM_AS_ROOT:
#     1.                     "Minimum" 42.000000 ################
#     2.                       "Range" 42.000000 ################
#     3.                    "Skewness" 41.000000 ###############
#     4.                    "Kurtosis" 32.000000 ############
#     5.                "90Percentile" 29.000000 ##########
#     6.                "10Percentile" 22.000000 ########
#     7.                      "Median" 17.000000 ######
#     8. "RobustMeanAbsoluteDeviation" 16.000000 #####
#     9.                        "Mean" 12.000000 ####
#    10.       "MeanAbsoluteDeviation"  9.000000 ##
#    11.                  "Uniformity"  9.000000 ##
#    12.                    "Variance"  7.000000 ##
#    13.             "RootMeanSquared"  3.000000
#    14.                      "Energy"  2.000000
#    15.          "InterquartileRange"  2.000000
#    16.                     "Maximum"  2.000000
#    17.                 "TotalEnergy"  2.000000
#
# Variable Importance: NUM_NODES:
#     1.                    "Skewness" 894.000000 ################
#     2.                "90Percentile" 716.000000 ############
#     3.                     "Maximum" 690.000000 ###########
#     4.                    "Kurtosis" 685.000000 ###########
#     5.                     "Minimum" 597.000000 #########
#     6.                      "Median" 584.000000 #########
#     7.                       "Range" 540.000000 ########
#     8.                "10Percentile" 535.000000 ########
#     9.                  "Uniformity" 501.000000 #######
#    10.                    "Variance" 453.000000 ######
#    11.                     "Entropy" 372.000000 #####
#    12.          "InterquartileRange" 330.000000 ####
#    13.                        "Mean" 318.000000 ####
#    14. "RobustMeanAbsoluteDeviation" 315.000000 ####
#    15.       "MeanAbsoluteDeviation" 246.000000 ##
#    16.             "RootMeanSquared" 141.000000
#    17.                 "TotalEnergy" 125.000000
#    18.                      "Energy" 122.000000
#
# Variable Importance: SUM_SCORE:
#     1.                     "Minimum" 48810.339603 ################
#     2.                "10Percentile" 47343.911376 ###############
#     3.                        "Mean" 33236.088650 ##########
#     4.                "90Percentile" 28583.403955 ########
#     5.                     "Maximum" 20937.519892 ######
#     6.                      "Median" 17728.949230 #####
#     7.                       "Range" 12644.527582 ###
#     8.                    "Kurtosis" 11543.104895 ##
#     9.          "InterquartileRange" 11201.134238 ##
#    10.                      "Energy" 10453.279864 ##
#    11.                    "Skewness" 8237.952978 #
#    12.             "RootMeanSquared" 7330.395663 #
#    13.                  "Uniformity" 6786.826290 #
#    14.                    "Variance" 5793.897272
#    15.       "MeanAbsoluteDeviation" 5385.914971
#    16.                 "TotalEnergy" 4304.637542
#    17.                     "Entropy" 3057.637013
#    18. "RobustMeanAbsoluteDeviation" 3018.065405
#
#
#
# Loss: BINOMIAL_LOG_LIKELIHOOD
# Validation loss value: 0.729807
# Number of trees per iteration: 1
# Node format: NOT_SET
# Number of trees: 289
# Total number of nodes: 16617
#
# Number of nodes by tree:
# Count: 289 Average: 57.4983 StdDev: 6.65519
# Min: 33 Max: 63 Ignored: 0
# ----------------------------------------------
# [ 33, 34)   1   0.35%   0.35%
# [ 34, 36)   2   0.69%   1.04%
# [ 36, 37)   0   0.00%   1.04%
# [ 37, 39)   0   0.00%   1.04%
# [ 39, 40)   2   0.69%   1.73%
# [ 40, 42)   4   1.38%   3.11%
# [ 42, 43)   0   0.00%   3.11%
# [ 43, 45)   7   2.42%   5.54% #
# [ 45, 46)   5   1.73%   7.27%
# [ 46, 48)  11   3.81%  11.07% #
# [ 48, 50)  23   7.96%  19.03% ##
# [ 50, 51)   0   0.00%  19.03%
# [ 51, 53)   4   1.38%  20.42%
# [ 53, 54)  10   3.46%  23.88% #
# [ 54, 56)  15   5.19%  29.07% #
# [ 56, 57)   0   0.00%  29.07%
# [ 57, 59)  32  11.07%  40.14% ###
# [ 59, 60)  25   8.65%  48.79% ##
# [ 60, 62)  40  13.84%  62.63% ####
# [ 62, 63] 108  37.37% 100.00% ##########
#
# Depth by leafs:
# Count: 8453 Average: 4.93387 StdDev: 0.328473
# Min: 2 Max: 5 Ignored: 0
# ----------------------------------------------
# [ 2, 3)   41   0.49%   0.49%
# [ 3, 4)   72   0.85%   1.34%
# [ 4, 5)  292   3.45%   4.79%
# [ 5, 5] 8048  95.21% 100.00% ##########
#
# Number of training obs by leaf:
# Count: 8453 Average: 12177.9 StdDev: 42731.9
# Min: 5 Max: 355459 Ignored: 0
# ----------------------------------------------
# [      5,  17777) 7460  88.25%  88.25% ##########
# [  17777,  35550)  402   4.76%  93.01% #
# [  35550,  53323)  170   2.01%  95.02%
# [  53323,  71096)   62   0.73%  95.75%
# [  71096,  88868)   39   0.46%  96.21%
# [  88868, 106641)   37   0.44%  96.65%
# [ 106641, 124414)   31   0.37%  97.02%
# [ 124414, 142187)   15   0.18%  97.20%
# [ 142187, 159959)   38   0.45%  97.65%
# [ 159959, 177732)   34   0.40%  98.05%
# [ 177732, 195505)   16   0.19%  98.24%
# [ 195505, 213278)   14   0.17%  98.40%
# [ 213278, 231050)   18   0.21%  98.62%
# [ 231050, 248823)   19   0.22%  98.84%
# [ 248823, 266596)   11   0.13%  98.97%
# [ 266596, 284369)   13   0.15%  99.12%
# [ 284369, 302141)   12   0.14%  99.27%
# [ 302141, 319914)   17   0.20%  99.47%
# [ 319914, 337687)   18   0.21%  99.68%
# [ 337687, 355459]   27   0.32% 100.00%
#
# Attribute in nodes:
# 	894 : Skewness [NUMERICAL]
# 	716 : 90Percentile [NUMERICAL]
# 	690 : Maximum [NUMERICAL]
# 	685 : Kurtosis [NUMERICAL]
# 	597 : Minimum [NUMERICAL]
# 	584 : Median [NUMERICAL]
# 	540 : Range [NUMERICAL]
# 	535 : 10Percentile [NUMERICAL]
# 	501 : Uniformity [NUMERICAL]
# 	453 : Variance [NUMERICAL]
# 	372 : Entropy [NUMERICAL]
# 	330 : InterquartileRange [NUMERICAL]
# 	318 : Mean [NUMERICAL]
# 	315 : RobustMeanAbsoluteDeviation [NUMERICAL]
# 	246 : MeanAbsoluteDeviation [NUMERICAL]
# 	141 : RootMeanSquared [NUMERICAL]
# 	125 : TotalEnergy [NUMERICAL]
# 	122 : Energy [NUMERICAL]
#
# Attribute in nodes with depth <= 0:
# 	42 : Range [NUMERICAL]
# 	42 : Minimum [NUMERICAL]
# 	41 : Skewness [NUMERICAL]
# 	32 : Kurtosis [NUMERICAL]
# 	29 : 90Percentile [NUMERICAL]
# 	22 : 10Percentile [NUMERICAL]
# 	17 : Median [NUMERICAL]
# 	16 : RobustMeanAbsoluteDeviation [NUMERICAL]
# 	12 : Mean [NUMERICAL]
# 	9 : Uniformity [NUMERICAL]
# 	9 : MeanAbsoluteDeviation [NUMERICAL]
# 	7 : Variance [NUMERICAL]
# 	3 : RootMeanSquared [NUMERICAL]
# 	2 : TotalEnergy [NUMERICAL]
# 	2 : Maximum [NUMERICAL]
# 	2 : InterquartileRange [NUMERICAL]
# 	2 : Energy [NUMERICAL]
#
# Attribute in nodes with depth <= 1:
# 	141 : Skewness [NUMERICAL]
# 	92 : Kurtosis [NUMERICAL]
# 	82 : Maximum [NUMERICAL]
# 	78 : Range [NUMERICAL]
# 	66 : Minimum [NUMERICAL]
# 	63 : Variance [NUMERICAL]
# 	58 : 90Percentile [NUMERICAL]
# 	49 : Median [NUMERICAL]
# 	47 : 10Percentile [NUMERICAL]
# 	43 : Uniformity [NUMERICAL]
# 	42 : RobustMeanAbsoluteDeviation [NUMERICAL]
# 	27 : Mean [NUMERICAL]
# 	24 : MeanAbsoluteDeviation [NUMERICAL]
# 	19 : Entropy [NUMERICAL]
# 	11 : RootMeanSquared [NUMERICAL]
# 	11 : InterquartileRange [NUMERICAL]
# 	10 : Energy [NUMERICAL]
# 	4 : TotalEnergy [NUMERICAL]
#
# Attribute in nodes with depth <= 2:
# 	273 : Skewness [NUMERICAL]
# 	212 : 90Percentile [NUMERICAL]
# 	191 : Kurtosis [NUMERICAL]
# 	153 : Range [NUMERICAL]
# 	153 : Maximum [NUMERICAL]
# 	142 : Median [NUMERICAL]
# 	139 : Minimum [NUMERICAL]
# 	128 : Variance [NUMERICAL]
# 	123 : 10Percentile [NUMERICAL]
# 	100 : Uniformity [NUMERICAL]
# 	74 : Entropy [NUMERICAL]
# 	70 : RobustMeanAbsoluteDeviation [NUMERICAL]
# 	56 : Mean [NUMERICAL]
# 	51 : MeanAbsoluteDeviation [NUMERICAL]
# 	49 : InterquartileRange [NUMERICAL]
# 	26 : RootMeanSquared [NUMERICAL]
# 	24 : Energy [NUMERICAL]
# 	18 : TotalEnergy [NUMERICAL]
#
# Attribute in nodes with depth <= 3:
# 	504 : Skewness [NUMERICAL]
# 	385 : 90Percentile [NUMERICAL]
# 	359 : Kurtosis [NUMERICAL]
# 	356 : Maximum [NUMERICAL]
# 	293 : Minimum [NUMERICAL]
# 	290 : Range [NUMERICAL]
# 	284 : Median [NUMERICAL]
# 	267 : 10Percentile [NUMERICAL]
# 	249 : Uniformity [NUMERICAL]
# 	244 : Variance [NUMERICAL]
# 	174 : Entropy [NUMERICAL]
# 	159 : RobustMeanAbsoluteDeviation [NUMERICAL]
# 	148 : InterquartileRange [NUMERICAL]
# 	140 : Mean [NUMERICAL]
# 	107 : MeanAbsoluteDeviation [NUMERICAL]
# 	74 : RootMeanSquared [NUMERICAL]
# 	65 : Energy [NUMERICAL]
# 	42 : TotalEnergy [NUMERICAL]
#
# Attribute in nodes with depth <= 5:
# 	894 : Skewness [NUMERICAL]
# 	716 : 90Percentile [NUMERICAL]
# 	690 : Maximum [NUMERICAL]
# 	685 : Kurtosis [NUMERICAL]
# 	597 : Minimum [NUMERICAL]
# 	584 : Median [NUMERICAL]
# 	540 : Range [NUMERICAL]
# 	535 : 10Percentile [NUMERICAL]
# 	501 : Uniformity [NUMERICAL]
# 	453 : Variance [NUMERICAL]
# 	372 : Entropy [NUMERICAL]
# 	330 : InterquartileRange [NUMERICAL]
# 	318 : Mean [NUMERICAL]
# 	315 : RobustMeanAbsoluteDeviation [NUMERICAL]
# 	246 : MeanAbsoluteDeviation [NUMERICAL]
# 	141 : RootMeanSquared [NUMERICAL]
# 	125 : TotalEnergy [NUMERICAL]
# 	122 : Energy [NUMERICAL]
#
# Condition type in nodes:
# 	8164 : HigherCondition
# Condition type in nodes with depth <= 0:
# 	289 : HigherCondition
# Condition type in nodes with depth <= 1:
# 	867 : HigherCondition
# Condition type in nodes with depth <= 2:
# 	1982 : HigherCondition
# Condition type in nodes with depth <= 3:
# 	4140 : HigherCondition
# Condition type in nodes with depth <= 5:
# 	8164 : HigherCondition
#
# Training logs:
# Number of iteration to final model: 289
# 	Iter:1 train-loss:1.307638 valid-loss:1.309120  train-accuracy:0.787644 valid-accuracy:0.783997
# 	Iter:2 train-loss:1.241197 valid-loss:1.243857  train-accuracy:0.797762 valid-accuracy:0.794496
# 	Iter:3 train-loss:1.183165 valid-loss:1.187275  train-accuracy:0.801813 valid-accuracy:0.799610
# 	Iter:4 train-loss:1.136178 valid-loss:1.141762  train-accuracy:0.805012 valid-accuracy:0.800116
# 	Iter:5 train-loss:1.094102 valid-loss:1.100886  train-accuracy:0.806549 valid-accuracy:0.803270
# 	Iter:6 train-loss:1.058239 valid-loss:1.065973  train-accuracy:0.807753 valid-accuracy:0.805046
# 	Iter:16 train-loss:0.873259 valid-loss:0.886626  train-accuracy:0.820148 valid-accuracy:0.815821
# 	Iter:26 train-loss:0.807749 valid-loss:0.827724  train-accuracy:0.825844 valid-accuracy:0.818475
# 	Iter:36 train-loss:0.777056 valid-loss:0.799531  train-accuracy:0.829610 valid-accuracy:0.820666
# 	Iter:46 train-loss:0.760003 valid-loss:0.784717  train-accuracy:0.832101 valid-accuracy:0.823001
# 	Iter:56 train-loss:0.747729 valid-loss:0.775688  train-accuracy:0.833718 valid-accuracy:0.824090
# 	Iter:66 train-loss:0.737943 valid-loss:0.768960  train-accuracy:0.836276 valid-accuracy:0.825749
# 	Iter:76 train-loss:0.730749 valid-loss:0.764247  train-accuracy:0.837726 valid-accuracy:0.825089
# 	Iter:86 train-loss:0.723085 valid-loss:0.760309  train-accuracy:0.839531 valid-accuracy:0.825743
# 	Iter:96 train-loss:0.716418 valid-loss:0.756539  train-accuracy:0.841000 valid-accuracy:0.827130
# 	Iter:106 train-loss:0.710349 valid-loss:0.754221  train-accuracy:0.842756 valid-accuracy:0.826845
# 	Iter:116 train-loss:0.704417 valid-loss:0.751724  train-accuracy:0.844650 valid-accuracy:0.827753
# 	Iter:126 train-loss:0.698627 valid-loss:0.748705  train-accuracy:0.846659 valid-accuracy:0.828179
# 	Iter:136 train-loss:0.694219 valid-loss:0.746956  train-accuracy:0.847535 valid-accuracy:0.828363
# 	Iter:146 train-loss:0.689143 valid-loss:0.745686  train-accuracy:0.849218 valid-accuracy:0.828456
# 	Iter:156 train-loss:0.685013 valid-loss:0.744132  train-accuracy:0.850177 valid-accuracy:0.828092
# 	Iter:166 train-loss:0.679874 valid-loss:0.742003  train-accuracy:0.851354 valid-accuracy:0.829802
# 	Iter:176 train-loss:0.676354 valid-loss:0.740985  train-accuracy:0.852377 valid-accuracy:0.829416
# 	Iter:186 train-loss:0.671220 valid-loss:0.738681  train-accuracy:0.853872 valid-accuracy:0.830682
# 	Iter:196 train-loss:0.667283 valid-loss:0.737309  train-accuracy:0.855074 valid-accuracy:0.830514
# 	Iter:206 train-loss:0.663846 valid-loss:0.736158  train-accuracy:0.856162 valid-accuracy:0.830300
# 	Iter:216 train-loss:0.660203 valid-loss:0.735409  train-accuracy:0.856988 valid-accuracy:0.831354
# 	Iter:226 train-loss:0.656781 valid-loss:0.734583  train-accuracy:0.858463 valid-accuracy:0.831186
# 	Iter:236 train-loss:0.653447 valid-loss:0.733678  train-accuracy:0.859234 valid-accuracy:0.831356
# 	Iter:246 train-loss:0.649525 valid-loss:0.732485  train-accuracy:0.860307 valid-accuracy:0.832073
# 	Iter:256 train-loss:0.646386 valid-loss:0.731788  train-accuracy:0.861365 valid-accuracy:0.832236
# 	Iter:266 train-loss:0.643051 valid-loss:0.730991  train-accuracy:0.862355 valid-accuracy:0.832528
# 	Iter:276 train-loss:0.640574 valid-loss:0.730303  train-accuracy:0.862888 valid-accuracy:0.833677
# 	Iter:286 train-loss:0.638191 valid-loss:0.730075  train-accuracy:0.863524 valid-accuracy:0.833286
# 	Iter:296 train-loss:0.635211 valid-loss:0.729976  train-accuracy:0.864586 valid-accuracy:0.832770

# %%
# Model features
model.make_inspector().features()
# Out:
# ["10Percentile" (1; #0),
#  "90Percentile" (1; #1),
#  "Energy" (1; #2),
#  "Entropy" (1; #3),
#  "InterquartileRange" (1; #4),
#  "Kurtosis" (1; #5),
#  "Maximum" (1; #6),
#  "Mean" (1; #7),
#  "MeanAbsoluteDeviation" (1; #8),
#  "Median" (1; #9),
#  "Minimum" (1; #10),
#  "Range" (1; #11),
#  "RobustMeanAbsoluteDeviation" (1; #12),
#  "RootMeanSquared" (1; #13),
#  "Skewness" (1; #14),
#  "TotalEnergy" (1; #15),
#  "Uniformity" (1; #16),
#  "Variance" (1; #17)]

# %%
# Feature importance
model.make_inspector().variable_importances()
# Out:
# {'INV_MEAN_MIN_DEPTH': [("Skewness" (1; #14), 0.22442443970185316),
#   ("Range" (1; #11), 0.21202148707465432),
#   ("Minimum" (1; #10), 0.21018386974096467),
#   ("90Percentile" (1; #1), 0.2084478431963311),
#   ("Kurtosis" (1; #5), 0.20738114282005712),
#   ("Maximum" (1; #6), 0.20033272124794732),
#   ("Median" (1; #9), 0.19922465581581755),
#   ("10Percentile" (1; #0), 0.19763195128085112),
#   ("Variance" (1; #17), 0.19131962675232742),
#   ("Uniformity" (1; #16), 0.19058809542839017),
#   ("RobustMeanAbsoluteDeviation" (1; #12), 0.1839713841061216),
#   ("Mean" (1; #7), 0.18234995819153857),
#   ("Entropy" (1; #3), 0.18009573301538295),
#   ("MeanAbsoluteDeviation" (1; #8), 0.17924946255436514),
#   ("InterquartileRange" (1; #4), 0.17842914522631204),
#   ("RootMeanSquared" (1; #13), 0.17465217904371214),
#   ("Energy" (1; #2), 0.17346794530759957),
#   ("TotalEnergy" (1; #15), 0.17236054390672506)],
#  'NUM_AS_ROOT': [("Minimum" (1; #10), 42.0),
#   ("Range" (1; #11), 42.0),
#   ("Skewness" (1; #14), 41.0),
#   ("Kurtosis" (1; #5), 32.0),
#   ("90Percentile" (1; #1), 29.0),
#   ("10Percentile" (1; #0), 22.0),
#   ("Median" (1; #9), 17.0),
#   ("RobustMeanAbsoluteDeviation" (1; #12), 16.0),
#   ("Mean" (1; #7), 12.0),
#   ("MeanAbsoluteDeviation" (1; #8), 9.0),
#   ("Uniformity" (1; #16), 9.0),
#   ("Variance" (1; #17), 7.0),
#   ("RootMeanSquared" (1; #13), 3.0),
#   ("Energy" (1; #2), 2.0),
#   ("InterquartileRange" (1; #4), 2.0),
#   ("Maximum" (1; #6), 2.0),
#   ("TotalEnergy" (1; #15), 2.0)],
#  'SUM_SCORE': [("Minimum" (1; #10), 48810.33960318621),
#   ("10Percentile" (1; #0), 47343.91137625074),
#   ("Mean" (1; #7), 33236.088649789046),
#   ("90Percentile" (1; #1), 28583.40395458145),
#   ("Maximum" (1; #6), 20937.51989173019),
#   ("Median" (1; #9), 17728.949229878643),
#   ("Range" (1; #11), 12644.52758160845),
#   ("Kurtosis" (1; #5), 11543.104895334935),
#   ("InterquartileRange" (1; #4), 11201.134237988816),
#   ("Energy" (1; #2), 10453.279864162569),
#   ("Skewness" (1; #14), 8237.952978396232),
#   ("RootMeanSquared" (1; #13), 7330.395662639763),
#   ("Uniformity" (1; #16), 6786.826290396249),
#   ("Variance" (1; #17), 5793.897271509705),
#   ("MeanAbsoluteDeviation" (1; #8), 5385.914970733828),
#   ("TotalEnergy" (1; #15), 4304.63754246621),
#   ("Entropy" (1; #3), 3057.6370126622487),
#   ("RobustMeanAbsoluteDeviation" (1; #12), 3018.0654046273166)],
#  'NUM_NODES': [("Skewness" (1; #14), 894.0),
#   ("90Percentile" (1; #1), 716.0),
#   ("Maximum" (1; #6), 690.0),
#   ("Kurtosis" (1; #5), 685.0),
#   ("Minimum" (1; #10), 597.0),
#   ("Median" (1; #9), 584.0),
#   ("Range" (1; #11), 540.0),
#   ("10Percentile" (1; #0), 535.0),
#   ("Uniformity" (1; #16), 501.0),
#   ("Variance" (1; #17), 453.0),
#   ("Entropy" (1; #3), 372.0),
#   ("InterquartileRange" (1; #4), 330.0),
#   ("Mean" (1; #7), 318.0),
#   ("RobustMeanAbsoluteDeviation" (1; #12), 315.0),
#   ("MeanAbsoluteDeviation" (1; #8), 246.0),
#   ("RootMeanSquared" (1; #13), 141.0),
#   ("TotalEnergy" (1; #15), 125.0),
#   ("Energy" (1; #2), 122.0)]}

# %%
# Model self evaluation
model.make_inspector().evaluation()
# Out:
# Evaluation(num_examples=None, accuracy=0.8327990174293518, loss=0.7298069596290588, rmse=None, ndcg=None, aucs=None, auuc=None, qini=None)

# %%
logs = model.make_inspector().training_logs()

plt.figure(figsize=(12, 4))
plt.subplot(1, 2, 1)
plt.plot([log.num_trees for log in logs], [log.evaluation.accuracy for log in logs])
plt.xlabel("Number of trees")
plt.ylabel("Accuracy (out-of-bag)")
plt.subplot(1, 2, 2)
plt.plot([log.num_trees for log in logs], [log.evaluation.loss for log in logs])
plt.xlabel("Number of trees")
plt.ylabel("Logloss (out-of-bag)")
plt.show()

# %% [markdown]
# Calculate the score of our hold-out validation dataset

# %%
predictions = model.predict(val_ds)
y_true      = validation_data["label"]

from sklearn.metrics import roc_auc_score
ROC_AUC = roc_auc_score(y_true, predictions)
print("The ROC AUC score is %.5f" % ROC_AUC )
# Out:
#  1/57 [..............................] - ETA: 3s
# 12/57 [=====>........................] - ETA: 0s
# 23/57 [===========>..................] - ETA: 0s
# 34/57 [================>.............] - ETA: 0s
# 46/57 [=======================>......] - ETA: 0s
# 57/57 [==============================] - 0s 5ms/step
# The ROC AUC score is 0.92032

# %%
# Compute binary classification metrics with sklearn
import numpy as np
from sklearn.metrics import (
    accuracy_score,
    precision_score,
    recall_score,
    f1_score,
    roc_auc_score,
    average_precision_score,
    confusion_matrix,
    classification_report,
    matthews_corrcoef,
    log_loss,
    brier_score_loss,
)

# Get predictions (probabilities or class labels)
preds = model.predict(test_ds)
# If model outputs probabilities, convert to labels by threshold 0.5
if preds.ndim == 2:
    # For TFDF classification, preds may be class probabilities with shape (N, 2)
    if preds.shape[1] == 2:
        pos_probs = preds[:, 1]
    else:
        # If single-probability column (positive class)
        pos_probs = preds[:, -1]
    y_pred = (pos_probs >= 0.5).astype(int)
else:
    # Already class labels
    y_pred = preds.astype(int)
    pos_probs = None

# Ground truth labels (must be 0/1 integers)
y_true = test_data["label"].astype(int).to_numpy()

# Core metrics
metrics = {}
metrics["accuracy"] = accuracy_score(y_true, y_pred)
metrics["precision"] = precision_score(y_true, y_pred, zero_division=0)
metrics["recall"] = recall_score(y_true, y_pred, zero_division=0)
metrics["f1"] = f1_score(y_true, y_pred, zero_division=0)
metrics["mcc"] = matthews_corrcoef(y_true, y_pred)

# Probabilistic metrics (only if we have probabilities)
if pos_probs is not None:
    metrics["roc_auc"] = roc_auc_score(y_true, pos_probs)
    metrics["pr_auc"] = average_precision_score(y_true, pos_probs)
    metrics["log_loss"] = log_loss(y_true, pos_probs, labels=[0,1])
    metrics["brier_score"] = brier_score_loss(y_true, pos_probs)

# Confusion matrix and detailed report
cm = confusion_matrix(y_true, y_pred, labels=[0,1])
report = classification_report(y_true, y_pred, digits=4)

print("Sklearn binary metrics:")
for k, v in metrics.items():
    print(f"{k}: {v:.4f}")
print("\nConfusion matrix:\n", cm)
print("\nClassification report:\n", report)
# Out:
#   1/114 [..............................] - ETA: 8s
#  12/114 [==>...........................] - ETA: 0s
#  23/114 [=====>........................] - ETA: 0s
#  35/114 [========>.....................] - ETA: 0s
#  46/114 [===========>..................] - ETA: 0s
#  56/114 [=============>................] - ETA: 0s
#  66/114 [================>.............] - ETA: 0s
#  78/114 [===================>..........] - ETA: 0s
#  89/114 [======================>.......] - ETA: 0s
# 100/114 [=========================>....] - ETA: 0s
# 111/114 [============================>.] - ETA: 0s
# 114/114 [==============================] - 1s 5ms/step
# Sklearn binary metrics:
# accuracy: 0.8636
# precision: 0.2961
# recall: 0.8158
# f1: 0.4345
# mcc: 0.4386
# roc_auc: 0.9209
# pr_auc: 0.6091
# log_loss: 0.3316
# brier_score: 0.1019
#
# Confusion matrix:
#  [[91751 14094]
#  [ 1339  5930]]
#
# Classification report:
#                precision    recall  f1-score   support
#
#            0     0.9856    0.8668    0.9224    105845
#            1     0.2961    0.8158    0.4345      7269
#
#     accuracy                         0.8636    113114
#    macro avg     0.6409    0.8413    0.6785    113114
# weighted avg     0.9413    0.8636    0.8911    113114
