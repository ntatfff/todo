# %%
# Import packages and modules
import numpy  as np
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow_decision_forests as tfdf

from sklearn.model_selection import train_test_split
# Out:
# 2026-07-04 09:15:08.935973: I tensorflow/core/util/port.cc:113] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2026-07-04 09:15:08.975433: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2026-07-04 09:15:13.324604: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
# Check the version of TensorFlow Decision Forests
print("Found TensorFlow Decision Forests v" + tfdf.__version__)
# Out:
# Found TensorFlow Decision Forests v1.9.1

# %%
datasetPath = 'dataset/firstorder/kernel5-radius5/dataset.csv'

# %%
# Parameters
datasetPath = "dataset/ngtdm/kernel5-radius5/300.dataset.csv"

# %%
# train/validation/test = 70/10/20
dataset = pd.read_csv(datasetPath)

train_data, temp_data = train_test_split(dataset, test_size=0.3, random_state=42)
validation_data, test_data = train_test_split(temp_data, test_size=2/3, random_state=42)

# %%
from sklearn.utils.class_weight import compute_class_weight

# tinh class weight tren tap train
classes = np.array([0, 1])
weights = compute_class_weight(class_weight="balanced", classes=classes, y=train_data["label"])
class_weight = {0: weights[0], 1: weights[1]}

# gan sample_weight cho tung dong
train_data["sample_weight"] = train_data["label"].map(class_weight)
validation_data["sample_weight"] = validation_data["label"].map(class_weight)
test_data["sample_weight"] = test_data["label"].map(class_weight)

# Convert the dataset into a TensorFlow dataset.
train_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    train_data, label="label", weight="sample_weight"
)         
val_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    validation_data, label="label", weight="sample_weight"
)
test_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    test_data, label="label", weight="sample_weight"
)
# Out:
# 2026-07-04 09:15:27.005508: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:984] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2026-07-04 09:15:27.006967: W tensorflow/core/common_runtime/gpu/gpu_device.cc:2251] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...

# %%
import keras

# %%
# %%time

# Train a Gradient Boosted Trees model.
model = tfdf.keras.GradientBoostedTreesModel()

# Add evaluation metrics
model.compile(
    metrics=["accuracy"]
)
model.fit(x=train_ds)

# # Train a Gradient Boosted Trees model.
# model = tfdf.keras.GradientBoostedTreesModel(num_trees=1500)
# model.fit(train_ds)
# Out:
# Use /tmp/tmpeftigjw5 as temporary training directory
# Reading training dataset...
# [WARNING 26-07-04 09:15:27.1347 UTC gradient_boosted_trees.cc:1840] "goss_alpha" set but "sampling_method" not equal to "GOSS".
# [WARNING 26-07-04 09:15:27.1347 UTC gradient_boosted_trees.cc:1851] "goss_beta" set but "sampling_method" not equal to "GOSS".
# [WARNING 26-07-04 09:15:27.1347 UTC gradient_boosted_trees.cc:1865] "selective_gradient_boosting_ratio" set but "sampling_method" not equal to "SELGB".
# Training dataset read in 0:00:02.764802. Found 235478 examples.
# Training model...
# Model trained in 0:00:31.463762
# Compiling model...
# [INFO 26-07-04 09:16:01.3744 UTC kernel.cc:1233] Loading model from path /tmp/tmpeftigjw5/model/ with prefix 94e71f023ed34112
# [INFO 26-07-04 09:16:01.3878 UTC quick_scorer_extended.cc:911] The binary was compiled without AVX2 support, but your CPU supports it. Enable it for faster model inference.
# [INFO 26-07-04 09:16:01.3887 UTC abstract_model.cc:1362] Engine "GradientBoostedTreesQuickScorerExtended" built
# [INFO 26-07-04 09:16:01.3888 UTC kernel.cc:1061] Use fast generic engine
# Model compiled.
# CPU times: user 2min 6s, sys: 1.45 s, total: 2min 7s
# Wall time: 37.2 s

# %%
# Evaluate the model
evaluate = model.evaluate(val_ds, return_dict=True)
print()

for name, value in evaluate.items():
    print(f"{name}: {value:.4f}")
# Out:
# WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
#  1/34 [..............................] - ETA: 1:35 - loss: 0.0000e+00 - accuracy: 0.8830
# 16/34 [=============>................] - ETA: 0s - loss: 0.0000e+00 - accuracy: 0.8779
# 30/34 [=========================>....] - ETA: 0s - loss: 0.0000e+00 - accuracy: 0.8769
# 34/34 [==============================] - 3s 4ms/step - loss: 0.0000e+00 - accuracy: 0.8769
# loss: 0.0000
# accuracy: 0.8769

# %%
# Model Summary
model.summary()
# Out:
# Model: "gradient_boosted_trees_model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
# =================================================================
# Total params: 1 (1.00 Byte)
# Trainable params: 0 (0.00 Byte)
# Non-trainable params: 1 (1.00 Byte)
# _________________________________________________________________
# Type: "GRADIENT_BOOSTED_TREES"
# Task: CLASSIFICATION
# Label: "__LABEL"
#
# Input Features (5):
# 	Busyness
# 	Coarseness
# 	Complexity
# 	Contrast
# 	Strength
#
# Trained with weights
#
# Variable Importance: INV_MEAN_MIN_DEPTH:
#     1.   "Busyness"  0.328544 ################
#     2.   "Contrast"  0.278954 ########
#     3. "Complexity"  0.272127 #######
#     4. "Coarseness"  0.247342 ####
#     5.   "Strength"  0.217058
#
# Variable Importance: NUM_AS_ROOT:
#     1.   "Contrast" 89.000000 ################
#     2.   "Busyness" 87.000000 ###############
#     3. "Coarseness" 64.000000 ###########
#     4. "Complexity" 51.000000 ########
#     5.   "Strength"  5.000000
#
# Variable Importance: NUM_NODES:
#     1.   "Busyness" 2160.000000 ################
#     2.   "Contrast" 1459.000000 ###
#     3. "Complexity" 1427.000000 ###
#     4. "Coarseness" 1352.000000 #
#     5.   "Strength" 1247.000000
#
# Variable Importance: SUM_SCORE:
#     1. "Coarseness" 98632.331494 ################
#     2.   "Busyness" 55997.227217 ########
#     3. "Complexity" 19994.838713 ##
#     4.   "Contrast" 8759.457790
#     5.   "Strength" 8373.709388
#
#
#
# Loss: BINOMIAL_LOG_LIKELIHOOD
# Validation loss value: 0.618116
# Number of trees per iteration: 1
# Node format: NOT_SET
# Number of trees: 296
# Total number of nodes: 15586
#
# Number of nodes by tree:
# Count: 296 Average: 52.6554 StdDev: 8.10756
# Min: 21 Max: 63 Ignored: 0
# ----------------------------------------------
# [ 21, 23)  1   0.34%   0.34%
# [ 23, 25)  0   0.00%   0.34%
# [ 25, 27)  0   0.00%   0.34%
# [ 27, 29)  1   0.34%   0.68%
# [ 29, 31)  0   0.00%   0.68%
# [ 31, 33)  1   0.34%   1.01%
# [ 33, 36)  2   0.68%   1.69%
# [ 36, 38)  7   2.36%   4.05% #
# [ 38, 40)  7   2.36%   6.42% #
# [ 40, 42)  9   3.04%   9.46% #
# [ 42, 44) 20   6.76%  16.22% ###
# [ 44, 46) 12   4.05%  20.27% ##
# [ 46, 48) 27   9.12%  29.39% ###
# [ 48, 51) 32  10.81%  40.20% ####
# [ 51, 53) 18   6.08%  46.28% ##
# [ 53, 55) 20   6.76%  53.04% ###
# [ 55, 57) 29   9.80%  62.84% ####
# [ 57, 59) 12   4.05%  66.89% ##
# [ 59, 61) 18   6.08%  72.97% ##
# [ 61, 63] 80  27.03% 100.00% ##########
#
# Depth by leafs:
# Count: 7941 Average: 4.86324 StdDev: 0.461526
# Min: 1 Max: 5 Ignored: 0
# ----------------------------------------------
# [ 1, 2)    2   0.03%   0.03%
# [ 2, 3)   58   0.73%   0.76%
# [ 3, 4)  191   2.41%   3.16%
# [ 4, 5)  522   6.57%   9.73% #
# [ 5, 5] 7168  90.27% 100.00% ##########
#
# Number of training obs by leaf:
# Count: 7941 Average: 7895.83 StdDev: 28553.1
# Min: 5 Max: 211284 Ignored: 0
# ----------------------------------------------
# [      5,  10569) 7084  89.21%  89.21% ##########
# [  10569,  21133)  248   3.12%  92.33%
# [  21133,  31697)  147   1.85%  94.18%
# [  31697,  42261)   81   1.02%  95.20%
# [  42261,  52825)   43   0.54%  95.74%
# [  52825,  63389)   38   0.48%  96.22%
# [  63389,  73953)   21   0.26%  96.49%
# [  73953,  84517)   30   0.38%  96.86%
# [  84517,  95081)   24   0.30%  97.17%
# [  95081, 105645)   24   0.30%  97.47%
# [ 105645, 116209)   13   0.16%  97.63%
# [ 116209, 126773)   18   0.23%  97.86%
# [ 126773, 137337)   10   0.13%  97.99%
# [ 137337, 147901)    9   0.11%  98.10%
# [ 147901, 158465)   17   0.21%  98.31%
# [ 158465, 169029)   30   0.38%  98.69%
# [ 169029, 179593)   34   0.43%  99.12%
# [ 179593, 190157)   21   0.26%  99.38%
# [ 190157, 200721)   18   0.23%  99.61%
# [ 200721, 211284]   31   0.39% 100.00%
#
# Attribute in nodes:
# 	2160 : Busyness [NUMERICAL]
# 	1459 : Contrast [NUMERICAL]
# 	1427 : Complexity [NUMERICAL]
# 	1352 : Coarseness [NUMERICAL]
# 	1247 : Strength [NUMERICAL]
#
# Attribute in nodes with depth <= 0:
# 	89 : Contrast [NUMERICAL]
# 	87 : Busyness [NUMERICAL]
# 	64 : Coarseness [NUMERICAL]
# 	51 : Complexity [NUMERICAL]
# 	5 : Strength [NUMERICAL]
#
# Attribute in nodes with depth <= 1:
# 	232 : Contrast [NUMERICAL]
# 	226 : Busyness [NUMERICAL]
# 	194 : Complexity [NUMERICAL]
# 	143 : Coarseness [NUMERICAL]
# 	91 : Strength [NUMERICAL]
#
# Attribute in nodes with depth <= 2:
# 	577 : Busyness [NUMERICAL]
# 	461 : Contrast [NUMERICAL]
# 	429 : Complexity [NUMERICAL]
# 	323 : Coarseness [NUMERICAL]
# 	218 : Strength [NUMERICAL]
#
# Attribute in nodes with depth <= 3:
# 	1140 : Busyness [NUMERICAL]
# 	851 : Contrast [NUMERICAL]
# 	801 : Complexity [NUMERICAL]
# 	700 : Coarseness [NUMERICAL]
# 	569 : Strength [NUMERICAL]
#
# Attribute in nodes with depth <= 5:
# 	2160 : Busyness [NUMERICAL]
# 	1459 : Contrast [NUMERICAL]
# 	1427 : Complexity [NUMERICAL]
# 	1352 : Coarseness [NUMERICAL]
# 	1247 : Strength [NUMERICAL]
#
# Condition type in nodes:
# 	7645 : HigherCondition
# Condition type in nodes with depth <= 0:
# 	296 : HigherCondition
# Condition type in nodes with depth <= 1:
# 	886 : HigherCondition
# Condition type in nodes with depth <= 2:
# 	2008 : HigherCondition
# Condition type in nodes with depth <= 3:
# 	4061 : HigherCondition
# Condition type in nodes with depth <= 5:
# 	7645 : HigherCondition
#
# Training logs:
# Number of iteration to final model: 296
# 	Iter:1 train-loss:1.288969 valid-loss:1.290367  train-accuracy:0.829512 valid-accuracy:0.822981
# 	Iter:2 train-loss:1.208232 valid-loss:1.210771  train-accuracy:0.836989 valid-accuracy:0.834974
# 	Iter:3 train-loss:1.141916 valid-loss:1.145469  train-accuracy:0.831254 valid-accuracy:0.827489
# 	Iter:4 train-loss:1.084275 valid-loss:1.088102  train-accuracy:0.835698 valid-accuracy:0.833228
# 	Iter:5 train-loss:1.035287 valid-loss:1.039541  train-accuracy:0.837168 valid-accuracy:0.835281
# 	Iter:6 train-loss:0.993276 valid-loss:0.998500  train-accuracy:0.837533 valid-accuracy:0.835063
# 	Iter:16 train-loss:0.768848 valid-loss:0.780306  train-accuracy:0.852037 valid-accuracy:0.849841
# 	Iter:26 train-loss:0.696186 valid-loss:0.711391  train-accuracy:0.857979 valid-accuracy:0.854765
# 	Iter:36 train-loss:0.660005 valid-loss:0.677640  train-accuracy:0.862150 valid-accuracy:0.862661
# 	Iter:46 train-loss:0.641810 valid-loss:0.662836  train-accuracy:0.864533 valid-accuracy:0.863876
# 	Iter:56 train-loss:0.626513 valid-loss:0.652382  train-accuracy:0.867055 valid-accuracy:0.864582
# 	Iter:66 train-loss:0.614651 valid-loss:0.644470  train-accuracy:0.868999 valid-accuracy:0.865467
# 	Iter:76 train-loss:0.606175 valid-loss:0.640341  train-accuracy:0.870663 valid-accuracy:0.865208
# 	Iter:86 train-loss:0.598917 valid-loss:0.635623  train-accuracy:0.871855 valid-accuracy:0.865357
# 	Iter:96 train-loss:0.592559 valid-loss:0.633464  train-accuracy:0.873305 valid-accuracy:0.866919
# 	Iter:106 train-loss:0.588117 valid-loss:0.632017  train-accuracy:0.874678 valid-accuracy:0.868027
# 	Iter:116 train-loss:0.583160 valid-loss:0.630378  train-accuracy:0.875454 valid-accuracy:0.868333
# 	Iter:126 train-loss:0.578426 valid-loss:0.629128  train-accuracy:0.876534 valid-accuracy:0.868036
# 	Iter:136 train-loss:0.573992 valid-loss:0.626974  train-accuracy:0.877532 valid-accuracy:0.868505
# 	Iter:146 train-loss:0.570006 valid-loss:0.626429  train-accuracy:0.878414 valid-accuracy:0.868751
# 	Iter:156 train-loss:0.565382 valid-loss:0.625085  train-accuracy:0.879496 valid-accuracy:0.868655
# 	Iter:166 train-loss:0.561902 valid-loss:0.624873  train-accuracy:0.880218 valid-accuracy:0.868581
# 	Iter:176 train-loss:0.557859 valid-loss:0.622778  train-accuracy:0.881169 valid-accuracy:0.869622
# 	Iter:186 train-loss:0.554627 valid-loss:0.621410  train-accuracy:0.882021 valid-accuracy:0.869749
# 	Iter:196 train-loss:0.552101 valid-loss:0.621459  train-accuracy:0.882862 valid-accuracy:0.869267
# 	Iter:206 train-loss:0.548272 valid-loss:0.620843  train-accuracy:0.883551 valid-accuracy:0.869445
# 	Iter:216 train-loss:0.544962 valid-loss:0.619732  train-accuracy:0.884489 valid-accuracy:0.869803
# 	Iter:226 train-loss:0.542454 valid-loss:0.619896  train-accuracy:0.885501 valid-accuracy:0.869253
# 	Iter:236 train-loss:0.539006 valid-loss:0.619496  train-accuracy:0.886202 valid-accuracy:0.870109
# 	Iter:246 train-loss:0.536128 valid-loss:0.619927  train-accuracy:0.887055 valid-accuracy:0.869262
# 	Iter:256 train-loss:0.533084 valid-loss:0.619424  train-accuracy:0.888205 valid-accuracy:0.869916
# 	Iter:266 train-loss:0.530371 valid-loss:0.619146  train-accuracy:0.889230 valid-accuracy:0.869092
# 	Iter:276 train-loss:0.528428 valid-loss:0.618835  train-accuracy:0.889777 valid-accuracy:0.868973
# 	Iter:286 train-loss:0.525188 valid-loss:0.618524  train-accuracy:0.890632 valid-accuracy:0.869040
# 	Iter:296 train-loss:0.521826 valid-loss:0.618116  train-accuracy:0.891204 valid-accuracy:0.869197

# %%
# Model features
model.make_inspector().features()
# Out:
# ["Busyness" (1; #0),
#  "Coarseness" (1; #1),
#  "Complexity" (1; #2),
#  "Contrast" (1; #3),
#  "Strength" (1; #4)]

# %%
# Feature importance
model.make_inspector().variable_importances()
# Out:
# {'INV_MEAN_MIN_DEPTH': [("Busyness" (1; #0), 0.32854399407042767),
#   ("Contrast" (1; #3), 0.27895420074338645),
#   ("Complexity" (1; #2), 0.2721273586964458),
#   ("Coarseness" (1; #1), 0.2473419465387507),
#   ("Strength" (1; #4), 0.21705755932614937)],
#  'NUM_AS_ROOT': [("Contrast" (1; #3), 89.0),
#   ("Busyness" (1; #0), 87.0),
#   ("Coarseness" (1; #1), 64.0),
#   ("Complexity" (1; #2), 51.0),
#   ("Strength" (1; #4), 5.0)],
#  'SUM_SCORE': [("Coarseness" (1; #1), 98632.33149385272),
#   ("Busyness" (1; #0), 55997.2272173886),
#   ("Complexity" (1; #2), 19994.83871338918),
#   ("Contrast" (1; #3), 8759.457789595092),
#   ("Strength" (1; #4), 8373.70938755089)],
#  'NUM_NODES': [("Busyness" (1; #0), 2160.0),
#   ("Contrast" (1; #3), 1459.0),
#   ("Complexity" (1; #2), 1427.0),
#   ("Coarseness" (1; #1), 1352.0),
#   ("Strength" (1; #4), 1247.0)]}

# %%
# Model self evaluation
model.make_inspector().evaluation()
# Out:
# Evaluation(num_examples=None, accuracy=0.8691965341567993, loss=0.6181161999702454, rmse=None, ndcg=None, aucs=None, auuc=None, qini=None)

# %%
logs = model.make_inspector().training_logs()

plt.figure(figsize=(12, 4))
plt.subplot(1, 2, 1)
plt.plot([log.num_trees for log in logs], [log.evaluation.accuracy for log in logs])
plt.xlabel("Number of trees")
plt.ylabel("Accuracy (out-of-bag)")
plt.subplot(1, 2, 2)
plt.plot([log.num_trees for log in logs], [log.evaluation.loss for log in logs])
plt.xlabel("Number of trees")
plt.ylabel("Logloss (out-of-bag)")
plt.show()

# %% [markdown]
# Calculate the score of our hold-out validation dataset

# %%
predictions = model.predict(val_ds)
y_true      = validation_data["label"]

from sklearn.metrics import roc_auc_score
ROC_AUC = roc_auc_score(y_true, predictions)
print("The ROC AUC score is %.5f" % ROC_AUC )
# Out:
#  1/34 [..............................] - ETA: 1s
# 16/34 [=============>................] - ETA: 0s
# 31/34 [==========================>...] - ETA: 0s
# 34/34 [==============================] - 0s 4ms/step
# The ROC AUC score is 0.94108

# %%
# Compute binary classification metrics with sklearn
import numpy as np
from sklearn.metrics import (
    accuracy_score,
    precision_score,
    recall_score,
    f1_score,
    roc_auc_score,
    average_precision_score,
    confusion_matrix,
    classification_report,
    matthews_corrcoef,
    log_loss,
    brier_score_loss,
)

# Get predictions (probabilities or class labels)
preds = model.predict(test_ds)
# If model outputs probabilities, convert to labels by threshold 0.5
if preds.ndim == 2:
    # For TFDF classification, preds may be class probabilities with shape (N, 2)
    if preds.shape[1] == 2:
        pos_probs = preds[:, 1]
    else:
        # If single-probability column (positive class)
        pos_probs = preds[:, -1]
    y_pred = (pos_probs >= 0.5).astype(int)
else:
    # Already class labels
    y_pred = preds.astype(int)
    pos_probs = None

# Ground truth labels (must be 0/1 integers)
y_true = test_data["label"].astype(int).to_numpy()

# Core metrics
metrics = {}
metrics["accuracy"] = accuracy_score(y_true, y_pred)
metrics["precision"] = precision_score(y_true, y_pred, zero_division=0)
metrics["recall"] = recall_score(y_true, y_pred, zero_division=0)
metrics["f1"] = f1_score(y_true, y_pred, zero_division=0)
metrics["mcc"] = matthews_corrcoef(y_true, y_pred)

# Probabilistic metrics (only if we have probabilities)
if pos_probs is not None:
    metrics["roc_auc"] = roc_auc_score(y_true, pos_probs)
    metrics["pr_auc"] = average_precision_score(y_true, pos_probs)
    metrics["log_loss"] = log_loss(y_true, pos_probs, labels=[0,1])
    metrics["brier_score"] = brier_score_loss(y_true, pos_probs)

# Confusion matrix and detailed report
cm = confusion_matrix(y_true, y_pred, labels=[0,1])
report = classification_report(y_true, y_pred, digits=4)

print("Sklearn binary metrics:")
for k, v in metrics.items():
    print(f"{k}: {v:.4f}")
print("\nConfusion matrix:\n", cm)
print("\nClassification report:\n", report)
# Out:
#  1/68 [..............................] - ETA: 3s
# 16/68 [======>.......................] - ETA: 0s
# 31/68 [============>.................] - ETA: 0s
# 45/68 [==================>...........] - ETA: 0s
# 60/68 [=========================>....] - ETA: 0s
# 68/68 [==============================] - 0s 4ms/step
# Sklearn binary metrics:
# accuracy: 0.8738
# precision: 0.3067
# recall: 0.8529
# f1: 0.4512
# mcc: 0.4642
# roc_auc: 0.9401
# pr_auc: 0.6122
# log_loss: 0.2903
# brier_score: 0.0907
#
# Confusion matrix:
#  [[55296  7891]
#  [  602  3491]]
#
# Classification report:
#                precision    recall  f1-score   support
#
#            0     0.9892    0.8751    0.9287     63187
#            1     0.3067    0.8529    0.4512      4093
#
#     accuracy                         0.8738     67280
#    macro avg     0.6480    0.8640    0.6899     67280
# weighted avg     0.9477    0.8738    0.8996     67280
