# %%
# Import packages and modules
import numpy  as np
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow_decision_forests as tfdf

from sklearn.model_selection import train_test_split
# Out:
# 2026-07-04 07:38:19.167223: I tensorflow/core/util/port.cc:113] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2026-07-04 07:38:19.219732: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2026-07-04 07:38:23.548645: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
# Check the version of TensorFlow Decision Forests
print("Found TensorFlow Decision Forests v" + tfdf.__version__)
# Out:
# Found TensorFlow Decision Forests v1.9.1

# %%
datasetPath = 'dataset/firstorder/kernel5-radius5/dataset.csv'

# %%
# Parameters
datasetPath = "dataset/firstorder/kernel5-radius5/400.dataset.csv"

# %%
# train/validation/test = 70/10/20
dataset = pd.read_csv(datasetPath)

train_data, temp_data = train_test_split(dataset, test_size=0.3, random_state=42)
validation_data, test_data = train_test_split(temp_data, test_size=2/3, random_state=42)

# %%
from sklearn.utils.class_weight import compute_class_weight

# tinh class weight tren tap train
classes = np.array([0, 1])
weights = compute_class_weight(class_weight="balanced", classes=classes, y=train_data["label"])
class_weight = {0: weights[0], 1: weights[1]}

# gan sample_weight cho tung dong
train_data["sample_weight"] = train_data["label"].map(class_weight)
validation_data["sample_weight"] = validation_data["label"].map(class_weight)
test_data["sample_weight"] = test_data["label"].map(class_weight)

# Convert the dataset into a TensorFlow dataset.
train_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    train_data, label="label", weight="sample_weight"
)         
val_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    validation_data, label="label", weight="sample_weight"
)
test_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    test_data, label="label", weight="sample_weight"
)
# Out:
# 2026-07-04 07:38:36.234082: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:984] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2026-07-04 07:38:36.235756: W tensorflow/core/common_runtime/gpu/gpu_device.cc:2251] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...

# %%
import keras

# %%
# %%time

# Train a Gradient Boosted Trees model.
model = tfdf.keras.GradientBoostedTreesModel()

# Add evaluation metrics
model.compile(
    metrics=["accuracy"]
)
model.fit(x=train_ds)

# # Train a Gradient Boosted Trees model.
# model = tfdf.keras.GradientBoostedTreesModel(num_trees=1500)
# model.fit(train_ds)
# Out:
# Use /tmp/tmp28rsqv53 as temporary training directory
# [WARNING 26-07-04 07:38:36.4249 UTC gradient_boosted_trees.cc:1840] "goss_alpha" set but "sampling_method" not equal to "GOSS".
# [WARNING 26-07-04 07:38:36.4250 UTC gradient_boosted_trees.cc:1851] "goss_beta" set but "sampling_method" not equal to "GOSS".
# [WARNING 26-07-04 07:38:36.4250 UTC gradient_boosted_trees.cc:1865] "selective_gradient_boosting_ratio" set but "sampling_method" not equal to "SELGB".
# Reading training dataset...
# Training dataset read in 0:00:03.874426. Found 315417 examples.
# Training model...
# Model trained in 0:01:20.793527
# Compiling model...
# [INFO 26-07-04 07:40:01.1075 UTC kernel.cc:1233] Loading model from path /tmp/tmp28rsqv53/model/ with prefix 80bfbe351dea46ed
# [INFO 26-07-04 07:40:01.1215 UTC quick_scorer_extended.cc:911] The binary was compiled without AVX2 support, but your CPU supports it. Enable it for faster model inference.
# [INFO 26-07-04 07:40:01.1226 UTC abstract_model.cc:1362] Engine "GradientBoostedTreesQuickScorerExtended" built
# [INFO 26-07-04 07:40:01.1226 UTC kernel.cc:1061] Use fast generic engine
# Model compiled.
# CPU times: user 10min 29s, sys: 4.74 s, total: 10min 34s
# Wall time: 1min 27s

# %%
# Evaluate the model
evaluate = model.evaluate(val_ds, return_dict=True)
print()

for name, value in evaluate.items():
    print(f"{name}: {value:.4f}")
# Out:
# WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
#  1/46 [..............................] - ETA: 2:15 - loss: 0.0000e+00 - accuracy: 0.8730
# 13/46 [=======>......................] - ETA: 0s - loss: 0.0000e+00 - accuracy: 0.8696
# 25/46 [===============>..............] - ETA: 0s - loss: 0.0000e+00 - accuracy: 0.8713
# 36/46 [======================>.......] - ETA: 0s - loss: 0.0000e+00 - accuracy: 0.8710
# 46/46 [==============================] - 3s 5ms/step - loss: 0.0000e+00 - accuracy: 0.8703
# loss: 0.0000
# accuracy: 0.8703

# %%
# Model Summary
model.summary()
# Out:
# Model: "gradient_boosted_trees_model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
# =================================================================
# Total params: 1 (1.00 Byte)
# Trainable params: 0 (0.00 Byte)
# Non-trainable params: 1 (1.00 Byte)
# _________________________________________________________________
# Type: "GRADIENT_BOOSTED_TREES"
# Task: CLASSIFICATION
# Label: "__LABEL"
#
# Input Features (18):
# 	10Percentile
# 	90Percentile
# 	Energy
# 	Entropy
# 	InterquartileRange
# 	Kurtosis
# 	Maximum
# 	Mean
# 	MeanAbsoluteDeviation
# 	Median
# 	Minimum
# 	Range
# 	RobustMeanAbsoluteDeviation
# 	RootMeanSquared
# 	Skewness
# 	TotalEnergy
# 	Uniformity
# 	Variance
#
# Trained with weights
#
# Variable Importance: INV_MEAN_MIN_DEPTH:
#     1.                       "Range"  0.217167 ################
#     2.                    "Skewness"  0.215595 ###############
#     3.                     "Minimum"  0.213590 ##############
#     4.                "10Percentile"  0.207705 ############
#     5.                    "Kurtosis"  0.202514 ##########
#     6.                "90Percentile"  0.199771 #########
#     7.                      "Median"  0.196430 ########
#     8.                     "Maximum"  0.196138 ########
#     9.                    "Variance"  0.190528 ######
#    10. "RobustMeanAbsoluteDeviation"  0.187380 #####
#    11.                        "Mean"  0.187268 #####
#    12.                  "Uniformity"  0.186763 ####
#    13.          "InterquartileRange"  0.184004 ###
#    14.                     "Entropy"  0.183443 ###
#    15.       "MeanAbsoluteDeviation"  0.181764 ###
#    16.             "RootMeanSquared"  0.177688 #
#    17.                 "TotalEnergy"  0.175785 #
#    18.                      "Energy"  0.173015
#
# Variable Importance: NUM_AS_ROOT:
#     1.                       "Range" 41.000000 ################
#     2.                     "Minimum" 33.000000 ############
#     3.                    "Skewness" 33.000000 ############
#     4.                "10Percentile" 31.000000 ############
#     5.                "90Percentile" 19.000000 #######
#     6.                    "Kurtosis" 16.000000 ######
#     7.                        "Mean" 15.000000 #####
#     8.                      "Median" 15.000000 #####
#     9. "RobustMeanAbsoluteDeviation" 13.000000 ####
#    10.                    "Variance" 10.000000 ###
#    11.             "RootMeanSquared"  9.000000 ###
#    12.          "InterquartileRange"  8.000000 ##
#    13.       "MeanAbsoluteDeviation"  8.000000 ##
#    14.                  "Uniformity"  7.000000 ##
#    15.                 "TotalEnergy"  6.000000 ##
#    16.                      "Energy"  2.000000
#    17.                     "Maximum"  1.000000
#
# Variable Importance: NUM_NODES:
#     1.                    "Skewness" 770.000000 ################
#     2.                    "Kurtosis" 615.000000 ############
#     3.                     "Minimum" 586.000000 ###########
#     4.                     "Maximum" 584.000000 ###########
#     5.                      "Median" 538.000000 ##########
#     6.                "90Percentile" 528.000000 ##########
#     7.                "10Percentile" 500.000000 #########
#     8.                       "Range" 491.000000 #########
#     9.                  "Uniformity" 432.000000 #######
#    10.                    "Variance" 409.000000 #######
#    11.                     "Entropy" 353.000000 #####
#    12.                        "Mean" 317.000000 #####
#    13. "RobustMeanAbsoluteDeviation" 317.000000 #####
#    14.          "InterquartileRange" 310.000000 ####
#    15.       "MeanAbsoluteDeviation" 273.000000 ####
#    16.             "RootMeanSquared" 129.000000
#    17.                 "TotalEnergy" 109.000000
#    18.                      "Energy" 105.000000
#
# Variable Importance: SUM_SCORE:
#     1.                        "Mean" 71200.947519 ################
#     2.                     "Maximum" 31174.371147 ######
#     3.                "90Percentile" 30226.471708 ######
#     4.                     "Minimum" 17033.686730 ###
#     5.                "10Percentile" 13859.569325 ##
#     6.                 "TotalEnergy" 13217.237629 ##
#     7.                    "Kurtosis" 11644.311699 ##
#     8.                      "Median" 6798.335020 #
#     9.                    "Skewness" 6459.144128
#    10.             "RootMeanSquared" 6138.546783
#    11.                      "Energy" 5861.928050
#    12.                       "Range" 5450.536311
#    13.                  "Uniformity" 4854.129529
#    14.          "InterquartileRange" 4685.426108
#    15.       "MeanAbsoluteDeviation" 4115.786963
#    16.                    "Variance" 3353.097358
#    17. "RobustMeanAbsoluteDeviation" 2650.000579
#    18.                     "Entropy" 2359.750818
#
#
#
# Loss: BINOMIAL_LOG_LIKELIHOOD
# Validation loss value: 0.696353
# Number of trees per iteration: 1
# Node format: NOT_SET
# Number of trees: 267
# Total number of nodes: 14999
#
# Number of nodes by tree:
# Count: 267 Average: 56.176 StdDev: 8.25682
# Min: 25 Max: 63 Ignored: 0
# ----------------------------------------------
# [ 25, 26)  1   0.37%   0.37%
# [ 26, 28)  1   0.37%   0.75%
# [ 28, 30)  1   0.37%   1.12%
# [ 30, 32)  6   2.25%   3.37% #
# [ 32, 34)  2   0.75%   4.12%
# [ 34, 36)  0   0.00%   4.12%
# [ 36, 38)  1   0.37%   4.49%
# [ 38, 40)  1   0.37%   4.87%
# [ 40, 42)  2   0.75%   5.62%
# [ 42, 44)  7   2.62%   8.24% #
# [ 44, 46) 10   3.75%  11.99% #
# [ 46, 48) 12   4.49%  16.48% ##
# [ 48, 50) 10   3.75%  20.22% #
# [ 50, 52) 15   5.62%  25.84% ##
# [ 52, 54) 14   5.24%  31.09% ##
# [ 54, 56) 11   4.12%  35.21% #
# [ 56, 58) 17   6.37%  41.57% ##
# [ 58, 60) 27  10.11%  51.69% ###
# [ 60, 62) 49  18.35%  70.04% ######
# [ 62, 63] 80  29.96% 100.00% ##########
#
# Depth by leafs:
# Count: 7633 Average: 4.92218 StdDev: 0.365514
# Min: 1 Max: 5 Ignored: 0
# ----------------------------------------------
# [ 1, 2)   11   0.14%   0.14%
# [ 2, 3)   26   0.34%   0.48%
# [ 3, 4)   92   1.21%   1.69%
# [ 4, 5)  288   3.77%   5.46%
# [ 5, 5] 7216  94.54% 100.00% ##########
#
# Number of training obs by leaf:
# Count: 7633 Average: 9926.26 StdDev: 34516.1
# Min: 5 Max: 283468 Ignored: 0
# ----------------------------------------------
# [      5,  14178) 6673  87.42%  87.42% ##########
# [  14178,  28351)  398   5.21%  92.64% #
# [  28351,  42524)  138   1.81%  94.45%
# [  42524,  56697)   99   1.30%  95.74%
# [  56697,  70871)   49   0.64%  96.38%
# [  70871,  85044)   34   0.45%  96.83%
# [  85044,  99217)   32   0.42%  97.25%
# [  99217, 113390)   23   0.30%  97.55%
# [ 113390, 127563)   18   0.24%  97.79%
# [ 127563, 141737)   15   0.20%  97.98%
# [ 141737, 155910)   15   0.20%  98.18%
# [ 155910, 170083)   14   0.18%  98.36%
# [ 170083, 184256)   11   0.14%  98.51%
# [ 184256, 198429)   14   0.18%  98.69%
# [ 198429, 212603)   12   0.16%  98.85%
# [ 212603, 226776)   14   0.18%  99.03%
# [ 226776, 240949)   15   0.20%  99.23%
# [ 240949, 255122)   15   0.20%  99.42%
# [ 255122, 269295)   15   0.20%  99.62%
# [ 269295, 283468]   29   0.38% 100.00%
#
# Attribute in nodes:
# 	770 : Skewness [NUMERICAL]
# 	615 : Kurtosis [NUMERICAL]
# 	586 : Minimum [NUMERICAL]
# 	584 : Maximum [NUMERICAL]
# 	538 : Median [NUMERICAL]
# 	528 : 90Percentile [NUMERICAL]
# 	500 : 10Percentile [NUMERICAL]
# 	491 : Range [NUMERICAL]
# 	432 : Uniformity [NUMERICAL]
# 	409 : Variance [NUMERICAL]
# 	353 : Entropy [NUMERICAL]
# 	317 : RobustMeanAbsoluteDeviation [NUMERICAL]
# 	317 : Mean [NUMERICAL]
# 	310 : InterquartileRange [NUMERICAL]
# 	273 : MeanAbsoluteDeviation [NUMERICAL]
# 	129 : RootMeanSquared [NUMERICAL]
# 	109 : TotalEnergy [NUMERICAL]
# 	105 : Energy [NUMERICAL]
#
# Attribute in nodes with depth <= 0:
# 	41 : Range [NUMERICAL]
# 	33 : Skewness [NUMERICAL]
# 	33 : Minimum [NUMERICAL]
# 	31 : 10Percentile [NUMERICAL]
# 	19 : 90Percentile [NUMERICAL]
# 	16 : Kurtosis [NUMERICAL]
# 	15 : Median [NUMERICAL]
# 	15 : Mean [NUMERICAL]
# 	13 : RobustMeanAbsoluteDeviation [NUMERICAL]
# 	10 : Variance [NUMERICAL]
# 	9 : RootMeanSquared [NUMERICAL]
# 	8 : MeanAbsoluteDeviation [NUMERICAL]
# 	8 : InterquartileRange [NUMERICAL]
# 	7 : Uniformity [NUMERICAL]
# 	6 : TotalEnergy [NUMERICAL]
# 	2 : Energy [NUMERICAL]
# 	1 : Maximum [NUMERICAL]
#
# Attribute in nodes with depth <= 1:
# 	92 : Skewness [NUMERICAL]
# 	82 : Kurtosis [NUMERICAL]
# 	79 : Range [NUMERICAL]
# 	75 : Minimum [NUMERICAL]
# 	62 : 10Percentile [NUMERICAL]
# 	51 : Maximum [NUMERICAL]
# 	51 : 90Percentile [NUMERICAL]
# 	46 : Variance [NUMERICAL]
# 	39 : Mean [NUMERICAL]
# 	36 : RobustMeanAbsoluteDeviation [NUMERICAL]
# 	36 : Median [NUMERICAL]
# 	32 : Uniformity [NUMERICAL]
# 	28 : Entropy [NUMERICAL]
# 	24 : MeanAbsoluteDeviation [NUMERICAL]
# 	24 : InterquartileRange [NUMERICAL]
# 	14 : RootMeanSquared [NUMERICAL]
# 	13 : TotalEnergy [NUMERICAL]
# 	6 : Energy [NUMERICAL]
#
# Attribute in nodes with depth <= 2:
# 	196 : Skewness [NUMERICAL]
# 	166 : Kurtosis [NUMERICAL]
# 	162 : Range [NUMERICAL]
# 	144 : Minimum [NUMERICAL]
# 	139 : Maximum [NUMERICAL]
# 	124 : 10Percentile [NUMERICAL]
# 	121 : Median [NUMERICAL]
# 	114 : 90Percentile [NUMERICAL]
# 	105 : Variance [NUMERICAL]
# 	90 : Entropy [NUMERICAL]
# 	83 : Mean [NUMERICAL]
# 	82 : Uniformity [NUMERICAL]
# 	81 : RobustMeanAbsoluteDeviation [NUMERICAL]
# 	68 : MeanAbsoluteDeviation [NUMERICAL]
# 	67 : InterquartileRange [NUMERICAL]
# 	33 : RootMeanSquared [NUMERICAL]
# 	19 : TotalEnergy [NUMERICAL]
# 	16 : Energy [NUMERICAL]
#
# Attribute in nodes with depth <= 3:
# 	407 : Skewness [NUMERICAL]
# 	336 : Kurtosis [NUMERICAL]
# 	292 : Minimum [NUMERICAL]
# 	280 : Maximum [NUMERICAL]
# 	272 : 90Percentile [NUMERICAL]
# 	270 : 10Percentile [NUMERICAL]
# 	263 : Median [NUMERICAL]
# 	258 : Range [NUMERICAL]
# 	212 : Variance [NUMERICAL]
# 	200 : Uniformity [NUMERICAL]
# 	173 : Entropy [NUMERICAL]
# 	168 : Mean [NUMERICAL]
# 	162 : InterquartileRange [NUMERICAL]
# 	160 : RobustMeanAbsoluteDeviation [NUMERICAL]
# 	135 : MeanAbsoluteDeviation [NUMERICAL]
# 	72 : RootMeanSquared [NUMERICAL]
# 	55 : TotalEnergy [NUMERICAL]
# 	43 : Energy [NUMERICAL]
#
# Attribute in nodes with depth <= 5:
# 	770 : Skewness [NUMERICAL]
# 	615 : Kurtosis [NUMERICAL]
# 	586 : Minimum [NUMERICAL]
# 	584 : Maximum [NUMERICAL]
# 	538 : Median [NUMERICAL]
# 	528 : 90Percentile [NUMERICAL]
# 	500 : 10Percentile [NUMERICAL]
# 	491 : Range [NUMERICAL]
# 	432 : Uniformity [NUMERICAL]
# 	409 : Variance [NUMERICAL]
# 	353 : Entropy [NUMERICAL]
# 	317 : RobustMeanAbsoluteDeviation [NUMERICAL]
# 	317 : Mean [NUMERICAL]
# 	310 : InterquartileRange [NUMERICAL]
# 	273 : MeanAbsoluteDeviation [NUMERICAL]
# 	129 : RootMeanSquared [NUMERICAL]
# 	109 : TotalEnergy [NUMERICAL]
# 	105 : Energy [NUMERICAL]
#
# Condition type in nodes:
# 	7366 : HigherCondition
# Condition type in nodes with depth <= 0:
# 	267 : HigherCondition
# Condition type in nodes with depth <= 1:
# 	790 : HigherCondition
# Condition type in nodes with depth <= 2:
# 	1810 : HigherCondition
# Condition type in nodes with depth <= 3:
# 	3758 : HigherCondition
# Condition type in nodes with depth <= 5:
# 	7366 : HigherCondition
#
# Training logs:
# Number of iteration to final model: 267
# 	Iter:1 train-loss:1.299274 valid-loss:1.300004  train-accuracy:0.809575 valid-accuracy:0.810463
# 	Iter:2 train-loss:1.227900 valid-loss:1.229018  train-accuracy:0.811391 valid-accuracy:0.812089
# 	Iter:3 train-loss:1.167526 valid-loss:1.168768  train-accuracy:0.813783 valid-accuracy:0.816331
# 	Iter:4 train-loss:1.115247 valid-loss:1.116755  train-accuracy:0.817006 valid-accuracy:0.820908
# 	Iter:5 train-loss:1.072486 valid-loss:1.074427  train-accuracy:0.817364 valid-accuracy:0.819949
# 	Iter:6 train-loss:1.032787 valid-loss:1.035474  train-accuracy:0.819826 valid-accuracy:0.823570
# 	Iter:16 train-loss:0.829353 valid-loss:0.839607  train-accuracy:0.833861 valid-accuracy:0.829074
# 	Iter:26 train-loss:0.756010 valid-loss:0.773051  train-accuracy:0.841608 valid-accuracy:0.834518
# 	Iter:36 train-loss:0.723756 valid-loss:0.747555  train-accuracy:0.846090 valid-accuracy:0.834800
# 	Iter:46 train-loss:0.706960 valid-loss:0.735900  train-accuracy:0.848862 valid-accuracy:0.834992
# 	Iter:56 train-loss:0.694112 valid-loss:0.727891  train-accuracy:0.850487 valid-accuracy:0.836957
# 	Iter:66 train-loss:0.684526 valid-loss:0.722325  train-accuracy:0.852198 valid-accuracy:0.838776
# 	Iter:76 train-loss:0.675521 valid-loss:0.717780  train-accuracy:0.853798 valid-accuracy:0.839747
# 	Iter:86 train-loss:0.668089 valid-loss:0.715950  train-accuracy:0.855310 valid-accuracy:0.839069
# 	Iter:96 train-loss:0.661695 valid-loss:0.713330  train-accuracy:0.856891 valid-accuracy:0.837973
# 	Iter:106 train-loss:0.655472 valid-loss:0.710761  train-accuracy:0.858343 valid-accuracy:0.838504
# 	Iter:116 train-loss:0.648891 valid-loss:0.708177  train-accuracy:0.859804 valid-accuracy:0.839109
# 	Iter:126 train-loss:0.644009 valid-loss:0.706998  train-accuracy:0.861202 valid-accuracy:0.839450
# 	Iter:136 train-loss:0.638705 valid-loss:0.706067  train-accuracy:0.861960 valid-accuracy:0.840072
# 	Iter:146 train-loss:0.633390 valid-loss:0.704522  train-accuracy:0.863095 valid-accuracy:0.840008
# 	Iter:156 train-loss:0.628464 valid-loss:0.703211  train-accuracy:0.864408 valid-accuracy:0.839867
# 	Iter:166 train-loss:0.623895 valid-loss:0.702033  train-accuracy:0.865432 valid-accuracy:0.839824
# 	Iter:176 train-loss:0.619177 valid-loss:0.700413  train-accuracy:0.866533 valid-accuracy:0.840627
# 	Iter:186 train-loss:0.613829 valid-loss:0.699255  train-accuracy:0.868026 valid-accuracy:0.840153
# 	Iter:196 train-loss:0.609556 valid-loss:0.698885  train-accuracy:0.869373 valid-accuracy:0.839924
# 	Iter:206 train-loss:0.606154 valid-loss:0.698616  train-accuracy:0.870515 valid-accuracy:0.839863
# 	Iter:216 train-loss:0.602157 valid-loss:0.698138  train-accuracy:0.871639 valid-accuracy:0.840387
# 	Iter:226 train-loss:0.597924 valid-loss:0.697467  train-accuracy:0.873083 valid-accuracy:0.840721
# 	Iter:236 train-loss:0.594539 valid-loss:0.696874  train-accuracy:0.873791 valid-accuracy:0.840509
# 	Iter:246 train-loss:0.591598 valid-loss:0.696798  train-accuracy:0.874811 valid-accuracy:0.840230
# 	Iter:256 train-loss:0.588882 valid-loss:0.696900  train-accuracy:0.875701 valid-accuracy:0.840419
# 	Iter:266 train-loss:0.584942 valid-loss:0.696532  train-accuracy:0.876564 valid-accuracy:0.840659
# 	Iter:276 train-loss:0.581308 valid-loss:0.696719  train-accuracy:0.877600 valid-accuracy:0.841696
# 	Iter:286 train-loss:0.578636 valid-loss:0.696667  train-accuracy:0.878313 valid-accuracy:0.841666
# 	Iter:296 train-loss:0.575561 valid-loss:0.696904  train-accuracy:0.879353 valid-accuracy:0.840654

# %%
# Model features
model.make_inspector().features()
# Out:
# ["10Percentile" (1; #0),
#  "90Percentile" (1; #1),
#  "Energy" (1; #2),
#  "Entropy" (1; #3),
#  "InterquartileRange" (1; #4),
#  "Kurtosis" (1; #5),
#  "Maximum" (1; #6),
#  "Mean" (1; #7),
#  "MeanAbsoluteDeviation" (1; #8),
#  "Median" (1; #9),
#  "Minimum" (1; #10),
#  "Range" (1; #11),
#  "RobustMeanAbsoluteDeviation" (1; #12),
#  "RootMeanSquared" (1; #13),
#  "Skewness" (1; #14),
#  "TotalEnergy" (1; #15),
#  "Uniformity" (1; #16),
#  "Variance" (1; #17)]

# %%
# Feature importance
model.make_inspector().variable_importances()
# Out:
# {'INV_MEAN_MIN_DEPTH': [("Range" (1; #11), 0.21716737821654328),
#   ("Skewness" (1; #14), 0.21559469316923735),
#   ("Minimum" (1; #10), 0.21359034525807943),
#   ("10Percentile" (1; #0), 0.20770513314129052),
#   ("Kurtosis" (1; #5), 0.20251428849482567),
#   ("90Percentile" (1; #1), 0.19977123098646096),
#   ("Median" (1; #9), 0.1964300632354706),
#   ("Maximum" (1; #6), 0.19613750166363716),
#   ("Variance" (1; #17), 0.1905280037290315),
#   ("RobustMeanAbsoluteDeviation" (1; #12), 0.18738034944723794),
#   ("Mean" (1; #7), 0.18726795649937056),
#   ("Uniformity" (1; #16), 0.18676270705652612),
#   ("InterquartileRange" (1; #4), 0.18400388300655954),
#   ("Entropy" (1; #3), 0.1834434420669912),
#   ("MeanAbsoluteDeviation" (1; #8), 0.18176420578860145),
#   ("RootMeanSquared" (1; #13), 0.17768800339818994),
#   ("TotalEnergy" (1; #15), 0.17578483612868448),
#   ("Energy" (1; #2), 0.1730148357667751)],
#  'SUM_SCORE': [("Mean" (1; #7), 71200.94751874811),
#   ("Maximum" (1; #6), 31174.371147466438),
#   ("90Percentile" (1; #1), 30226.47170779164),
#   ("Minimum" (1; #10), 17033.686729771503),
#   ("10Percentile" (1; #0), 13859.56932526737),
#   ("TotalEnergy" (1; #15), 13217.237628792196),
#   ("Kurtosis" (1; #5), 11644.31169887518),
#   ("Median" (1; #9), 6798.335020489518),
#   ("Skewness" (1; #14), 6459.144128288447),
#   ("RootMeanSquared" (1; #13), 6138.546783052162),
#   ("Energy" (1; #2), 5861.928050033699),
#   ("Range" (1; #11), 5450.536310850697),
#   ("Uniformity" (1; #16), 4854.129528829219),
#   ("InterquartileRange" (1; #4), 4685.426108017199),
#   ("MeanAbsoluteDeviation" (1; #8), 4115.786962584094),
#   ("Variance" (1; #17), 3353.0973579832885),
#   ("RobustMeanAbsoluteDeviation" (1; #12), 2650.0005787064656),
#   ("Entropy" (1; #3), 2359.750818091689)],
#  'NUM_AS_ROOT': [("Range" (1; #11), 41.0),
#   ("Minimum" (1; #10), 33.0),
#   ("Skewness" (1; #14), 33.0),
#   ("10Percentile" (1; #0), 31.0),
#   ("90Percentile" (1; #1), 19.0),
#   ("Kurtosis" (1; #5), 16.0),
#   ("Mean" (1; #7), 15.0),
#   ("Median" (1; #9), 15.0),
#   ("RobustMeanAbsoluteDeviation" (1; #12), 13.0),
#   ("Variance" (1; #17), 10.0),
#   ("RootMeanSquared" (1; #13), 9.0),
#   ("InterquartileRange" (1; #4), 8.0),
#   ("MeanAbsoluteDeviation" (1; #8), 8.0),
#   ("Uniformity" (1; #16), 7.0),
#   ("TotalEnergy" (1; #15), 6.0),
#   ("Energy" (1; #2), 2.0),
#   ("Maximum" (1; #6), 1.0)],
#  'NUM_NODES': [("Skewness" (1; #14), 770.0),
#   ("Kurtosis" (1; #5), 615.0),
#   ("Minimum" (1; #10), 586.0),
#   ("Maximum" (1; #6), 584.0),
#   ("Median" (1; #9), 538.0),
#   ("90Percentile" (1; #1), 528.0),
#   ("10Percentile" (1; #0), 500.0),
#   ("Range" (1; #11), 491.0),
#   ("Uniformity" (1; #16), 432.0),
#   ("Variance" (1; #17), 409.0),
#   ("Entropy" (1; #3), 353.0),
#   ("Mean" (1; #7), 317.0),
#   ("RobustMeanAbsoluteDeviation" (1; #12), 317.0),
#   ("InterquartileRange" (1; #4), 310.0),
#   ("MeanAbsoluteDeviation" (1; #8), 273.0),
#   ("RootMeanSquared" (1; #13), 129.0),
#   ("TotalEnergy" (1; #15), 109.0),
#   ("Energy" (1; #2), 105.0)]}

# %%
# Model self evaluation
model.make_inspector().evaluation()
# Out:
# Evaluation(num_examples=None, accuracy=0.8409261107444763, loss=0.6963534355163574, rmse=None, ndcg=None, aucs=None, auuc=None, qini=None)

# %%
logs = model.make_inspector().training_logs()

plt.figure(figsize=(12, 4))
plt.subplot(1, 2, 1)
plt.plot([log.num_trees for log in logs], [log.evaluation.accuracy for log in logs])
plt.xlabel("Number of trees")
plt.ylabel("Accuracy (out-of-bag)")
plt.subplot(1, 2, 2)
plt.plot([log.num_trees for log in logs], [log.evaluation.loss for log in logs])
plt.xlabel("Number of trees")
plt.ylabel("Logloss (out-of-bag)")
plt.show()

# %% [markdown]
# Calculate the score of our hold-out validation dataset

# %%
predictions = model.predict(val_ds)
y_true      = validation_data["label"]

from sklearn.metrics import roc_auc_score
ROC_AUC = roc_auc_score(y_true, predictions)
print("The ROC AUC score is %.5f" % ROC_AUC )
# Out:
#  1/46 [..............................] - ETA: 3s
# 12/46 [======>.......................] - ETA: 0s
# 24/46 [==============>...............] - ETA: 0s
# 35/46 [=====================>........] - ETA: 0s
# 46/46 [==============================] - 0s 4ms/step
# The ROC AUC score is 0.92266

# %%
# Compute binary classification metrics with sklearn
import numpy as np
from sklearn.metrics import (
    accuracy_score,
    precision_score,
    recall_score,
    f1_score,
    roc_auc_score,
    average_precision_score,
    confusion_matrix,
    classification_report,
    matthews_corrcoef,
    log_loss,
    brier_score_loss,
)

# Get predictions (probabilities or class labels)
preds = model.predict(test_ds)
# If model outputs probabilities, convert to labels by threshold 0.5
if preds.ndim == 2:
    # For TFDF classification, preds may be class probabilities with shape (N, 2)
    if preds.shape[1] == 2:
        pos_probs = preds[:, 1]
    else:
        # If single-probability column (positive class)
        pos_probs = preds[:, -1]
    y_pred = (pos_probs >= 0.5).astype(int)
else:
    # Already class labels
    y_pred = preds.astype(int)
    pos_probs = None

# Ground truth labels (must be 0/1 integers)
y_true = test_data["label"].astype(int).to_numpy()

# Core metrics
metrics = {}
metrics["accuracy"] = accuracy_score(y_true, y_pred)
metrics["precision"] = precision_score(y_true, y_pred, zero_division=0)
metrics["recall"] = recall_score(y_true, y_pred, zero_division=0)
metrics["f1"] = f1_score(y_true, y_pred, zero_division=0)
metrics["mcc"] = matthews_corrcoef(y_true, y_pred)

# Probabilistic metrics (only if we have probabilities)
if pos_probs is not None:
    metrics["roc_auc"] = roc_auc_score(y_true, pos_probs)
    metrics["pr_auc"] = average_precision_score(y_true, pos_probs)
    metrics["log_loss"] = log_loss(y_true, pos_probs, labels=[0,1])
    metrics["brier_score"] = brier_score_loss(y_true, pos_probs)

# Confusion matrix and detailed report
cm = confusion_matrix(y_true, y_pred, labels=[0,1])
report = classification_report(y_true, y_pred, digits=4)

print("Sklearn binary metrics:")
for k, v in metrics.items():
    print(f"{k}: {v:.4f}")
print("\nConfusion matrix:\n", cm)
print("\nClassification report:\n", report)
# Out:
#  1/91 [..............................] - ETA: 5s
# 12/91 [==>...........................] - ETA: 0s
# 22/91 [======>.......................] - ETA: 0s
# 34/91 [==========>...................] - ETA: 0s
# 46/91 [==============>...............] - ETA: 0s
# 56/91 [=================>............] - ETA: 0s
# 67/91 [=====================>........] - ETA: 0s
# 78/91 [========================>.....] - ETA: 0s
# 90/91 [============================>.] - ETA: 0s
# 91/91 [==============================] - 0s 5ms/step
# Sklearn binary metrics:
# accuracy: 0.8723
# precision: 0.3062
# recall: 0.8284
# f1: 0.4471
# mcc: 0.4543
# roc_auc: 0.9272
# pr_auc: 0.6256
# log_loss: 0.3119
# brier_score: 0.0953
#
# Confusion matrix:
#  [[73961 10542]
#  [  964  4653]]
#
# Classification report:
#                precision    recall  f1-score   support
#
#            0     0.9871    0.8752    0.9278     84503
#            1     0.3062    0.8284    0.4471      5617
#
#     accuracy                         0.8723     90120
#    macro avg     0.6467    0.8518    0.6875     90120
# weighted avg     0.9447    0.8723    0.8979     90120
