# %%
# Import packages and modules
import numpy  as np
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow_decision_forests as tfdf

from sklearn.model_selection import train_test_split
# Out:
# 2026-07-04 08:41:21.312990: I tensorflow/core/util/port.cc:113] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2026-07-04 08:41:21.354620: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2026-07-04 08:41:25.538959: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
# Check the version of TensorFlow Decision Forests
print("Found TensorFlow Decision Forests v" + tfdf.__version__)
# Out:
# Found TensorFlow Decision Forests v1.9.1

# %%
datasetPath = 'dataset/firstorder/kernel5-radius5/dataset.csv'

# %%
# Parameters
datasetPath = "dataset/gldm/kernel5-radius5/200.dataset.csv"

# %%
# train/validation/test = 70/10/20
dataset = pd.read_csv(datasetPath)

train_data, temp_data = train_test_split(dataset, test_size=0.3, random_state=42)
validation_data, test_data = train_test_split(temp_data, test_size=2/3, random_state=42)

# %%
from sklearn.utils.class_weight import compute_class_weight

# tinh class weight tren tap train
classes = np.array([0, 1])
weights = compute_class_weight(class_weight="balanced", classes=classes, y=train_data["label"])
class_weight = {0: weights[0], 1: weights[1]}

# gan sample_weight cho tung dong
train_data["sample_weight"] = train_data["label"].map(class_weight)
validation_data["sample_weight"] = validation_data["label"].map(class_weight)
test_data["sample_weight"] = test_data["label"].map(class_weight)

# Convert the dataset into a TensorFlow dataset.
train_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    train_data, label="label", weight="sample_weight"
)         
val_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    validation_data, label="label", weight="sample_weight"
)
test_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    test_data, label="label", weight="sample_weight"
)
# Out:
# 2026-07-04 08:41:37.560386: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:984] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2026-07-04 08:41:37.561788: W tensorflow/core/common_runtime/gpu/gpu_device.cc:2251] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...

# %%
import keras

# %%
# %%time

# Train a Random Forest model.
model = tfdf.keras.RandomForestModel()

# Add evaluation metrics
model.compile(
    metrics=["accuracy"]
)
model.fit(x=train_ds)

# # Train a Gradient Boosted Trees model.
# model = tfdf.keras.GradientBoostedTreesModel(num_trees=1500)
# model.fit(train_ds)
# Out:
# Use /tmp/tmp0tqd7oln as temporary training directory
# Reading training dataset...
# Training dataset read in 0:00:04.598263. Found 157612 examples.
# Training model...
# [INFO 26-07-04 08:41:57.2952 UTC kernel.cc:1233] Loading model from path /tmp/tmp0tqd7oln/model/ with prefix 2de5c7cf71424792
# [INFO 26-07-04 08:41:58.5370 UTC decision_forest.cc:734] Model loaded with 300 root(s), 1068872 node(s), and 14 input feature(s).
# [INFO 26-07-04 08:41:58.5370 UTC abstract_model.cc:1362] Engine "RandomForestOptPred" built
# [INFO 26-07-04 08:41:58.5370 UTC kernel.cc:1061] Use fast generic engine
# Model trained in 0:00:16.423733
# Compiling model...
# Model compiled.
# CPU times: user 3min 3s, sys: 1.49 s, total: 3min 5s
# Wall time: 24.5 s

# %%
# Evaluate the model
evaluate = model.evaluate(val_ds, return_dict=True)
print()

for name, value in evaluate.items():
    print(f"{name}: {value:.4f}")
# Out:
# WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
#  1/23 [>.............................] - ETA: 1:05 - loss: 0.0000e+00 - accuracy: 0.9490
#  3/23 [==>...........................] - ETA: 0s - loss: 0.0000e+00 - accuracy: 0.9360
#  5/23 [=====>........................] - ETA: 0s - loss: 0.0000e+00 - accuracy: 0.9358
#  7/23 [========>.....................] - ETA: 0s - loss: 0.0000e+00 - accuracy: 0.9360
#  9/23 [==========>...................] - ETA: 0s - loss: 0.0000e+00 - accuracy: 0.9342
# 11/23 [=============>................] - ETA: 0s - loss: 0.0000e+00 - accuracy: 0.9348
# 13/23 [===============>..............] - ETA: 0s - loss: 0.0000e+00 - accuracy: 0.9341
# 15/23 [==================>...........] - ETA: 0s - loss: 0.0000e+00 - accuracy: 0.9340
# 17/23 [=====================>........] - ETA: 0s - loss: 0.0000e+00 - accuracy: 0.9343
# 19/23 [=======================>......] - ETA: 0s - loss: 0.0000e+00 - accuracy: 0.9344
# 21/23 [==========================>...] - ETA: 0s - loss: 0.0000e+00 - accuracy: 0.9335
# 23/23 [==============================] - 4s 29ms/step - loss: 0.0000e+00 - accuracy: 0.9328
# loss: 0.0000
# accuracy: 0.9328

# %%
# Model Summary
model.summary()
# Out:
# Model: "random_forest_model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
# =================================================================
# Total params: 1 (1.00 Byte)
# Trainable params: 0 (0.00 Byte)
# Non-trainable params: 1 (1.00 Byte)
# _________________________________________________________________
# Type: "RANDOM_FOREST"
# Task: CLASSIFICATION
# Label: "__LABEL"
#
# Input Features (14):
# 	DependenceEntropy
# 	DependenceNonUniformity
# 	DependenceNonUniformityNormalized
# 	DependenceVariance
# 	GrayLevelNonUniformity
# 	GrayLevelVariance
# 	HighGrayLevelEmphasis
# 	LargeDependenceEmphasis
# 	LargeDependenceHighGrayLevelEmphasis
# 	LargeDependenceLowGrayLevelEmphasis
# 	LowGrayLevelEmphasis
# 	SmallDependenceEmphasis
# 	SmallDependenceHighGrayLevelEmphasis
# 	SmallDependenceLowGrayLevelEmphasis
#
# Trained with weights
#
# Variable Importance: INV_MEAN_MIN_DEPTH:
#     1.                "HighGrayLevelEmphasis"  0.214416 ################
#     2.                 "LowGrayLevelEmphasis"  0.171253 ##########
#     3. "LargeDependenceHighGrayLevelEmphasis"  0.157180 #########
#     4.                    "DependenceEntropy"  0.153929 ########
#     5. "SmallDependenceHighGrayLevelEmphasis"  0.132030 ######
#     6.  "SmallDependenceLowGrayLevelEmphasis"  0.115554 ####
#     7.               "GrayLevelNonUniformity"  0.108900 ###
#     8.  "LargeDependenceLowGrayLevelEmphasis"  0.107468 ###
#     9.              "SmallDependenceEmphasis"  0.103551 ##
#    10.                    "GrayLevelVariance"  0.095360 #
#    11.                   "DependenceVariance"  0.085571
#    12.              "LargeDependenceEmphasis"  0.085533
#    13.              "DependenceNonUniformity"  0.080442
#    14.    "DependenceNonUniformityNormalized"  0.079974
#
# Variable Importance: NUM_AS_ROOT:
#     1.                 "LowGrayLevelEmphasis" 108.000000 ################
#     2.                "HighGrayLevelEmphasis" 78.000000 ###########
#     3.  "LargeDependenceLowGrayLevelEmphasis" 36.000000 #####
#     4. "LargeDependenceHighGrayLevelEmphasis" 35.000000 #####
#     5.  "SmallDependenceLowGrayLevelEmphasis" 20.000000 ##
#     6. "SmallDependenceHighGrayLevelEmphasis" 13.000000 #
#     7.                    "DependenceEntropy"  5.000000
#     8.               "GrayLevelNonUniformity"  3.000000
#     9.                   "DependenceVariance"  1.000000
#    10.                    "GrayLevelVariance"  1.000000
#
# Variable Importance: NUM_NODES:
#     1.                    "DependenceEntropy" 47610.000000 ################
#     2. "LargeDependenceHighGrayLevelEmphasis" 47224.000000 ###############
#     3.               "GrayLevelNonUniformity" 44942.000000 #############
#     4.  "SmallDependenceLowGrayLevelEmphasis" 42655.000000 ############
#     5. "SmallDependenceHighGrayLevelEmphasis" 41275.000000 ###########
#     6.                    "GrayLevelVariance" 41060.000000 ##########
#     7.              "SmallDependenceEmphasis" 40891.000000 ##########
#     8.                "HighGrayLevelEmphasis" 39815.000000 #########
#     9.                 "LowGrayLevelEmphasis" 35786.000000 ######
#    10.  "LargeDependenceLowGrayLevelEmphasis" 34550.000000 #####
#    11.                   "DependenceVariance" 33454.000000 ####
#    12.              "LargeDependenceEmphasis" 30520.000000 ##
#    13.    "DependenceNonUniformityNormalized" 27357.000000
#    14.              "DependenceNonUniformity" 27147.000000
#
# Variable Importance: SUM_SCORE:
#     1.                "HighGrayLevelEmphasis" 4572861.088857 ################
#     2.                 "LowGrayLevelEmphasis" 3448619.353670 ###########
#     3.                    "DependenceEntropy" 3280987.979981 ##########
#     4. "LargeDependenceHighGrayLevelEmphasis" 3022499.192592 #########
#     5. "SmallDependenceHighGrayLevelEmphasis" 2163356.833987 ######
#     6.  "SmallDependenceLowGrayLevelEmphasis" 1940189.059370 #####
#     7.               "GrayLevelNonUniformity" 1728154.528712 ####
#     8.  "LargeDependenceLowGrayLevelEmphasis" 1579547.360286 ####
#     9.              "SmallDependenceEmphasis" 1526148.579080 ###
#    10.                    "GrayLevelVariance" 1203271.718388 ##
#    11.                   "DependenceVariance" 737630.029301
#    12.              "LargeDependenceEmphasis" 733721.855066
#    13.              "DependenceNonUniformity" 532773.225792
#    14.    "DependenceNonUniformityNormalized" 516095.682246
#
#
#
# Winner takes all: true
# Out-of-bag evaluation: accuracy:0.854107 logloss:0.441686
# Number of trees: 300
# Total number of nodes: 1068872
#
# Number of nodes by tree:
# Count: 300 Average: 3562.91 StdDev: 198.939
# Min: 2949 Max: 4069 Ignored: 0
# ----------------------------------------------
# [ 2949, 3005)  2   0.67%   0.67%
# [ 3005, 3061)  1   0.33%   1.00%
# [ 3061, 3117)  4   1.33%   2.33% #
# [ 3117, 3173)  3   1.00%   3.33% #
# [ 3173, 3229)  5   1.67%   5.00% #
# [ 3229, 3285) 10   3.33%   8.33% ##
# [ 3285, 3341) 15   5.00%  13.33% ###
# [ 3341, 3397) 20   6.67%  20.00% #####
# [ 3397, 3453) 20   6.67%  26.67% #####
# [ 3453, 3509) 25   8.33%  35.00% ######
# [ 3509, 3565) 40  13.33%  48.33% #########
# [ 3565, 3621) 44  14.67%  63.00% ##########
# [ 3621, 3677) 31  10.33%  73.33% #######
# [ 3677, 3733) 19   6.33%  79.67% ####
# [ 3733, 3789) 22   7.33%  87.00% #####
# [ 3789, 3845) 13   4.33%  91.33% ###
# [ 3845, 3901) 12   4.00%  95.33% ###
# [ 3901, 3957)  8   2.67%  98.00% ##
# [ 3957, 4013)  4   1.33%  99.33% #
# [ 4013, 4069]  2   0.67% 100.00%
#
# Depth by leafs:
# Count: 534586 Average: 12.8065 StdDev: 2.12475
# Min: 3 Max: 15 Ignored: 0
# ----------------------------------------------
# [  3,  4)      4   0.00%   0.00%
# [  4,  5)     68   0.01%   0.01%
# [  5,  6)    557   0.10%   0.12%
# [  6,  7)   2121   0.40%   0.51%
# [  7,  8)   5834   1.09%   1.61%
# [  8,  9)  12926   2.42%   4.02% #
# [  9, 10)  24199   4.53%   8.55% ##
# [ 10, 11)  38940   7.28%  15.83% ##
# [ 11, 12)  54549  10.20%  26.04% ###
# [ 12, 13)  68988  12.90%  38.94% ####
# [ 13, 14)  79565  14.88%  53.83% #####
# [ 14, 15)  85801  16.05%  69.88% #####
# [ 15, 15] 161034  30.12% 100.00% ##########
#
# Number of training obs by leaf:
# Count: 534586 Average: 88.449 StdDev: 450.037
# Min: 5 Max: 19626 Ignored: 0
# ----------------------------------------------
# [     5,   986) 526923  98.57%  98.57% ##########
# [   986,  1967)   3854   0.72%  99.29%
# [  1967,  2948)   1553   0.29%  99.58%
# [  2948,  3929)    815   0.15%  99.73%
# [  3929,  4910)    442   0.08%  99.81%
# [  4910,  5891)    270   0.05%  99.86%
# [  5891,  6872)    184   0.03%  99.90%
# [  6872,  7853)    145   0.03%  99.93%
# [  7853,  8834)    116   0.02%  99.95%
# [  8834,  9816)     76   0.01%  99.96%
# [  9816, 10797)     64   0.01%  99.97%
# [ 10797, 11778)     49   0.01%  99.98%
# [ 11778, 12759)     26   0.00%  99.99%
# [ 12759, 13740)     16   0.00%  99.99%
# [ 13740, 14721)     13   0.00%  99.99%
# [ 14721, 15702)     16   0.00% 100.00%
# [ 15702, 16683)     15   0.00% 100.00%
# [ 16683, 17664)      4   0.00% 100.00%
# [ 17664, 18645)      4   0.00% 100.00%
# [ 18645, 19626]      1   0.00% 100.00%
#
# Attribute in nodes:
# 	47610 : DependenceEntropy [NUMERICAL]
# 	47224 : LargeDependenceHighGrayLevelEmphasis [NUMERICAL]
# 	44942 : GrayLevelNonUniformity [NUMERICAL]
# 	42655 : SmallDependenceLowGrayLevelEmphasis [NUMERICAL]
# 	41275 : SmallDependenceHighGrayLevelEmphasis [NUMERICAL]
# 	41060 : GrayLevelVariance [NUMERICAL]
# 	40891 : SmallDependenceEmphasis [NUMERICAL]
# 	39815 : HighGrayLevelEmphasis [NUMERICAL]
# 	35786 : LowGrayLevelEmphasis [NUMERICAL]
# 	34550 : LargeDependenceLowGrayLevelEmphasis [NUMERICAL]
# 	33454 : DependenceVariance [NUMERICAL]
# 	30520 : LargeDependenceEmphasis [NUMERICAL]
# 	27357 : DependenceNonUniformityNormalized [NUMERICAL]
# 	27147 : DependenceNonUniformity [NUMERICAL]
#
# Attribute in nodes with depth <= 0:
# 	108 : LowGrayLevelEmphasis [NUMERICAL]
# 	78 : HighGrayLevelEmphasis [NUMERICAL]
# 	36 : LargeDependenceLowGrayLevelEmphasis [NUMERICAL]
# 	35 : LargeDependenceHighGrayLevelEmphasis [NUMERICAL]
# 	20 : SmallDependenceLowGrayLevelEmphasis [NUMERICAL]
# 	13 : SmallDependenceHighGrayLevelEmphasis [NUMERICAL]
# 	5 : DependenceEntropy [NUMERICAL]
# 	3 : GrayLevelNonUniformity [NUMERICAL]
# 	1 : GrayLevelVariance [NUMERICAL]
# 	1 : DependenceVariance [NUMERICAL]
#
# Attribute in nodes with depth <= 1:
# 	253 : HighGrayLevelEmphasis [NUMERICAL]
# 	205 : LowGrayLevelEmphasis [NUMERICAL]
# 	159 : LargeDependenceHighGrayLevelEmphasis [NUMERICAL]
# 	66 : LargeDependenceLowGrayLevelEmphasis [NUMERICAL]
# 	60 : DependenceEntropy [NUMERICAL]
# 	57 : SmallDependenceHighGrayLevelEmphasis [NUMERICAL]
# 	56 : SmallDependenceLowGrayLevelEmphasis [NUMERICAL]
# 	18 : GrayLevelNonUniformity [NUMERICAL]
# 	11 : SmallDependenceEmphasis [NUMERICAL]
# 	9 : GrayLevelVariance [NUMERICAL]
# 	3 : DependenceVariance [NUMERICAL]
# 	2 : LargeDependenceEmphasis [NUMERICAL]
# 	1 : DependenceNonUniformityNormalized [NUMERICAL]
#
# Attribute in nodes with depth <= 2:
# 	512 : HighGrayLevelEmphasis [NUMERICAL]
# 	352 : LargeDependenceHighGrayLevelEmphasis [NUMERICAL]
# 	288 : LowGrayLevelEmphasis [NUMERICAL]
# 	218 : SmallDependenceHighGrayLevelEmphasis [NUMERICAL]
# 	173 : DependenceEntropy [NUMERICAL]
# 	125 : SmallDependenceLowGrayLevelEmphasis [NUMERICAL]
# 	113 : LargeDependenceLowGrayLevelEmphasis [NUMERICAL]
# 	91 : SmallDependenceEmphasis [NUMERICAL]
# 	81 : GrayLevelNonUniformity [NUMERICAL]
# 	46 : GrayLevelVariance [NUMERICAL]
# 	41 : LargeDependenceEmphasis [NUMERICAL]
# 	40 : DependenceVariance [NUMERICAL]
# 	11 : DependenceNonUniformity [NUMERICAL]
# 	9 : DependenceNonUniformityNormalized [NUMERICAL]
#
# Attribute in nodes with depth <= 3:
# 	930 : HighGrayLevelEmphasis [NUMERICAL]
# 	687 : LargeDependenceHighGrayLevelEmphasis [NUMERICAL]
# 	590 : DependenceEntropy [NUMERICAL]
# 	438 : LowGrayLevelEmphasis [NUMERICAL]
# 	377 : SmallDependenceHighGrayLevelEmphasis [NUMERICAL]
# 	296 : GrayLevelNonUniformity [NUMERICAL]
# 	295 : SmallDependenceLowGrayLevelEmphasis [NUMERICAL]
# 	251 : SmallDependenceEmphasis [NUMERICAL]
# 	203 : GrayLevelVariance [NUMERICAL]
# 	194 : LargeDependenceLowGrayLevelEmphasis [NUMERICAL]
# 	81 : LargeDependenceEmphasis [NUMERICAL]
# 	81 : DependenceVariance [NUMERICAL]
# 	42 : DependenceNonUniformityNormalized [NUMERICAL]
# 	31 : DependenceNonUniformity [NUMERICAL]
#
# Attribute in nodes with depth <= 5:
# 	2623 : DependenceEntropy [NUMERICAL]
# 	2551 : LargeDependenceHighGrayLevelEmphasis [NUMERICAL]
# 	2495 : HighGrayLevelEmphasis [NUMERICAL]
# 	1492 : GrayLevelNonUniformity [NUMERICAL]
# 	1350 : SmallDependenceLowGrayLevelEmphasis [NUMERICAL]
# 	1350 : SmallDependenceEmphasis [NUMERICAL]
# 	1261 : SmallDependenceHighGrayLevelEmphasis [NUMERICAL]
# 	1248 : LowGrayLevelEmphasis [NUMERICAL]
# 	1157 : GrayLevelVariance [NUMERICAL]
# 	726 : LargeDependenceLowGrayLevelEmphasis [NUMERICAL]
# 	578 : LargeDependenceEmphasis [NUMERICAL]
# 	513 : DependenceVariance [NUMERICAL]
# 	391 : DependenceNonUniformity [NUMERICAL]
# 	376 : DependenceNonUniformityNormalized [NUMERICAL]
#
# Condition type in nodes:
# 	534286 : HigherCondition
# Condition type in nodes with depth <= 0:
# 	300 : HigherCondition
# Condition type in nodes with depth <= 1:
# 	900 : HigherCondition
# Condition type in nodes with depth <= 2:
# 	2100 : HigherCondition
# Condition type in nodes with depth <= 3:
# 	4496 : HigherCondition
# Condition type in nodes with depth <= 5:
# 	18111 : HigherCondition
# Node format: NOT_SET
#
# Training OOB:
# 	trees: 1, Out-of-bag evaluation: accuracy:0.820334 logloss:6.47581
# 	trees: 11, Out-of-bag evaluation: accuracy:0.83033 logloss:2.62671
# 	trees: 21, Out-of-bag evaluation: accuracy:0.839846 logloss:1.51738
# 	trees: 32, Out-of-bag evaluation: accuracy:0.845826 logloss:1.18186
# 	trees: 42, Out-of-bag evaluation: accuracy:0.849357 logloss:0.972487
# 	trees: 52, Out-of-bag evaluation: accuracy:0.849169 logloss:0.858473
# 	trees: 62, Out-of-bag evaluation: accuracy:0.849666 logloss:0.778978
# 	trees: 72, Out-of-bag evaluation: accuracy:0.85034 logloss:0.723394
# 	trees: 82, Out-of-bag evaluation: accuracy:0.85132 logloss:0.686251
# 	trees: 92, Out-of-bag evaluation: accuracy:0.851369 logloss:0.637146
# 	trees: 102, Out-of-bag evaluation: accuracy:0.851887 logloss:0.612443
# 	trees: 112, Out-of-bag evaluation: accuracy:0.851915 logloss:0.587523
# 	trees: 122, Out-of-bag evaluation: accuracy:0.852346 logloss:0.568652
# 	trees: 132, Out-of-bag evaluation: accuracy:0.852069 logloss:0.548907
# 	trees: 142, Out-of-bag evaluation: accuracy:0.852859 logloss:0.538084
# 	trees: 152, Out-of-bag evaluation: accuracy:0.852755 logloss:0.523228
# 	trees: 162, Out-of-bag evaluation: accuracy:0.8531 logloss:0.51386
# 	trees: 172, Out-of-bag evaluation: accuracy:0.853113 logloss:0.501588
# 	trees: 182, Out-of-bag evaluation: accuracy:0.85381 logloss:0.496109
# 	trees: 192, Out-of-bag evaluation: accuracy:0.854082 logloss:0.492111
# 	trees: 202, Out-of-bag evaluation: accuracy:0.853512 logloss:0.485565
# 	trees: 212, Out-of-bag evaluation: accuracy:0.853952 logloss:0.478786
# 	trees: 222, Out-of-bag evaluation: accuracy:0.854513 logloss:0.474258
# 	trees: 232, Out-of-bag evaluation: accuracy:0.854258 logloss:0.470697
# 	trees: 242, Out-of-bag evaluation: accuracy:0.854134 logloss:0.467605
# 	trees: 252, Out-of-bag evaluation: accuracy:0.854336 logloss:0.459183
# 	trees: 262, Out-of-bag evaluation: accuracy:0.85421 logloss:0.453635
# 	trees: 272, Out-of-bag evaluation: accuracy:0.853808 logloss:0.453215
# 	trees: 282, Out-of-bag evaluation: accuracy:0.854103 logloss:0.448153
# 	trees: 292, Out-of-bag evaluation: accuracy:0.854115 logloss:0.442535
# 	trees: 300, Out-of-bag evaluation: accuracy:0.854107 logloss:0.441686

# %%
# Model features
model.make_inspector().features()
# Out:
# ["DependenceEntropy" (1; #0),
#  "DependenceNonUniformity" (1; #1),
#  "DependenceNonUniformityNormalized" (1; #2),
#  "DependenceVariance" (1; #3),
#  "GrayLevelNonUniformity" (1; #4),
#  "GrayLevelVariance" (1; #5),
#  "HighGrayLevelEmphasis" (1; #6),
#  "LargeDependenceEmphasis" (1; #7),
#  "LargeDependenceHighGrayLevelEmphasis" (1; #8),
#  "LargeDependenceLowGrayLevelEmphasis" (1; #9),
#  "LowGrayLevelEmphasis" (1; #10),
#  "SmallDependenceEmphasis" (1; #11),
#  "SmallDependenceHighGrayLevelEmphasis" (1; #12),
#  "SmallDependenceLowGrayLevelEmphasis" (1; #13)]

# %%
# Feature importance
model.make_inspector().variable_importances()
# Out:
# {'INV_MEAN_MIN_DEPTH': [("HighGrayLevelEmphasis" (1; #6), 0.21441633936173235),
#   ("LowGrayLevelEmphasis" (1; #10), 0.1712531518677241),
#   ("LargeDependenceHighGrayLevelEmphasis" (1; #8), 0.15718041004748828),
#   ("DependenceEntropy" (1; #0), 0.15392928340437725),
#   ("SmallDependenceHighGrayLevelEmphasis" (1; #12), 0.1320298497542622),
#   ("SmallDependenceLowGrayLevelEmphasis" (1; #13), 0.1155537865623187),
#   ("GrayLevelNonUniformity" (1; #4), 0.10890036546709203),
#   ("LargeDependenceLowGrayLevelEmphasis" (1; #9), 0.10746840645934032),
#   ("SmallDependenceEmphasis" (1; #11), 0.10355057405606156),
#   ("GrayLevelVariance" (1; #5), 0.09536045029649774),
#   ("DependenceVariance" (1; #3), 0.08557126316879603),
#   ("LargeDependenceEmphasis" (1; #7), 0.08553268383583086),
#   ("DependenceNonUniformity" (1; #1), 0.08044175389856903),
#   ("DependenceNonUniformityNormalized" (1; #2), 0.07997442693813121)],
#  'NUM_AS_ROOT': [("LowGrayLevelEmphasis" (1; #10), 108.0),
#   ("HighGrayLevelEmphasis" (1; #6), 78.0),
#   ("LargeDependenceLowGrayLevelEmphasis" (1; #9), 36.0),
#   ("LargeDependenceHighGrayLevelEmphasis" (1; #8), 35.0),
#   ("SmallDependenceLowGrayLevelEmphasis" (1; #13), 20.0),
#   ("SmallDependenceHighGrayLevelEmphasis" (1; #12), 13.0),
#   ("DependenceEntropy" (1; #0), 5.0),
#   ("GrayLevelNonUniformity" (1; #4), 3.0),
#   ("DependenceVariance" (1; #3), 1.0),
#   ("GrayLevelVariance" (1; #5), 1.0)],
#  'SUM_SCORE': [("HighGrayLevelEmphasis" (1; #6), 4572861.0888571665),
#   ("LowGrayLevelEmphasis" (1; #10), 3448619.353670302),
#   ("DependenceEntropy" (1; #0), 3280987.9799814685),
#   ("LargeDependenceHighGrayLevelEmphasis" (1; #8), 3022499.1925921263),
#   ("SmallDependenceHighGrayLevelEmphasis" (1; #12), 2163356.8339874144),
#   ("SmallDependenceLowGrayLevelEmphasis" (1; #13), 1940189.0593695883),
#   ("GrayLevelNonUniformity" (1; #4), 1728154.5287115201),
#   ("LargeDependenceLowGrayLevelEmphasis" (1; #9), 1579547.36028551),
#   ("SmallDependenceEmphasis" (1; #11), 1526148.5790796606),
#   ("GrayLevelVariance" (1; #5), 1203271.718387885),
#   ("DependenceVariance" (1; #3), 737630.0293007114),
#   ("LargeDependenceEmphasis" (1; #7), 733721.8550663071),
#   ("DependenceNonUniformity" (1; #1), 532773.2257921549),
#   ("DependenceNonUniformityNormalized" (1; #2), 516095.6822457637)],
#  'NUM_NODES': [("DependenceEntropy" (1; #0), 47610.0),
#   ("LargeDependenceHighGrayLevelEmphasis" (1; #8), 47224.0),
#   ("GrayLevelNonUniformity" (1; #4), 44942.0),
#   ("SmallDependenceLowGrayLevelEmphasis" (1; #13), 42655.0),
#   ("SmallDependenceHighGrayLevelEmphasis" (1; #12), 41275.0),
#   ("GrayLevelVariance" (1; #5), 41060.0),
#   ("SmallDependenceEmphasis" (1; #11), 40891.0),
#   ("HighGrayLevelEmphasis" (1; #6), 39815.0),
#   ("LowGrayLevelEmphasis" (1; #10), 35786.0),
#   ("LargeDependenceLowGrayLevelEmphasis" (1; #9), 34550.0),
#   ("DependenceVariance" (1; #3), 33454.0),
#   ("LargeDependenceEmphasis" (1; #7), 30520.0),
#   ("DependenceNonUniformityNormalized" (1; #2), 27357.0),
#   ("DependenceNonUniformity" (1; #1), 27147.0)]}

# %%
# Model self evaluation
model.make_inspector().evaluation()
# Out:
# Evaluation(num_examples=157612, accuracy=0.8541067248985637, loss=0.4416859649717783, rmse=None, ndcg=None, aucs=None, auuc=None, qini=None)

# %%
logs = model.make_inspector().training_logs()

plt.figure(figsize=(12, 4))
plt.subplot(1, 2, 1)
plt.plot([log.num_trees for log in logs], [log.evaluation.accuracy for log in logs])
plt.xlabel("Number of trees")
plt.ylabel("Accuracy (out-of-bag)")
plt.subplot(1, 2, 2)
plt.plot([log.num_trees for log in logs], [log.evaluation.loss for log in logs])
plt.xlabel("Number of trees")
plt.ylabel("Logloss (out-of-bag)")
plt.show()

# %% [markdown]
# Calculate the score of our hold-out validation dataset

# %%
predictions = model.predict(val_ds)
y_true      = validation_data["label"]

from sklearn.metrics import roc_auc_score
ROC_AUC = roc_auc_score(y_true, predictions)
print("The ROC AUC score is %.5f" % ROC_AUC )
# Out:
#  1/23 [>.............................] - ETA: 1s
#  3/23 [==>...........................] - ETA: 0s
#  5/23 [=====>........................] - ETA: 0s
#  7/23 [========>.....................] - ETA: 0s
#  9/23 [==========>...................] - ETA: 0s
# 11/23 [=============>................] - ETA: 0s
# 13/23 [===============>..............] - ETA: 0s
# 15/23 [==================>...........] - ETA: 0s
# 17/23 [=====================>........] - ETA: 0s
# 19/23 [=======================>......] - ETA: 0s
# 21/23 [==========================>...] - ETA: 0s
# 23/23 [==============================] - 1s 29ms/step
# The ROC AUC score is 0.95372

# %%
# Compute binary classification metrics with sklearn
import numpy as np
from sklearn.metrics import (
    accuracy_score,
    precision_score,
    recall_score,
    f1_score,
    roc_auc_score,
    average_precision_score,
    confusion_matrix,
    classification_report,
    matthews_corrcoef,
    log_loss,
    brier_score_loss,
)

# Get predictions (probabilities or class labels)
preds = model.predict(test_ds)
# If model outputs probabilities, convert to labels by threshold 0.5
if preds.ndim == 2:
    # For TFDF classification, preds may be class probabilities with shape (N, 2)
    if preds.shape[1] == 2:
        pos_probs = preds[:, 1]
    else:
        # If single-probability column (positive class)
        pos_probs = preds[:, -1]
    y_pred = (pos_probs >= 0.5).astype(int)
else:
    # Already class labels
    y_pred = preds.astype(int)
    pos_probs = None

# Ground truth labels (must be 0/1 integers)
y_true = test_data["label"].astype(int).to_numpy()

# Core metrics
metrics = {}
metrics["accuracy"] = accuracy_score(y_true, y_pred)
metrics["precision"] = precision_score(y_true, y_pred, zero_division=0)
metrics["recall"] = recall_score(y_true, y_pred, zero_division=0)
metrics["f1"] = f1_score(y_true, y_pred, zero_division=0)
metrics["mcc"] = matthews_corrcoef(y_true, y_pred)

# Probabilistic metrics (only if we have probabilities)
if pos_probs is not None:
    metrics["roc_auc"] = roc_auc_score(y_true, pos_probs)
    metrics["pr_auc"] = average_precision_score(y_true, pos_probs)
    metrics["log_loss"] = log_loss(y_true, pos_probs, labels=[0,1])
    metrics["brier_score"] = brier_score_loss(y_true, pos_probs)

# Confusion matrix and detailed report
cm = confusion_matrix(y_true, y_pred, labels=[0,1])
report = classification_report(y_true, y_pred, digits=4)

print("Sklearn binary metrics:")
for k, v in metrics.items():
    print(f"{k}: {v:.4f}")
print("\nConfusion matrix:\n", cm)
print("\nClassification report:\n", report)
# Out:
#  1/46 [..............................] - ETA: 4s
#  3/46 [>.............................] - ETA: 1s
#  5/46 [==>...........................] - ETA: 1s
#  7/46 [===>..........................] - ETA: 1s
#  9/46 [====>.........................] - ETA: 1s
# 11/46 [======>.......................] - ETA: 1s
# 13/46 [=======>......................] - ETA: 1s
# 15/46 [========>.....................] - ETA: 0s
# 17/46 [==========>...................] - ETA: 0s
# 19/46 [===========>..................] - ETA: 0s
# 21/46 [============>.................] - ETA: 0s
# 23/46 [==============>...............] - ETA: 0s
# 25/46 [===============>..............] - ETA: 0s
# 27/46 [================>.............] - ETA: 0s
# 29/46 [=================>............] - ETA: 0s
# 31/46 [===================>..........] - ETA: 0s
# 33/46 [====================>.........] - ETA: 0s
# 35/46 [=====================>........] - ETA: 0s
# 37/46 [=======================>......] - ETA: 0s
# 39/46 [========================>.....] - ETA: 0s
# 41/46 [=========================>....] - ETA: 0s
# 43/46 [===========================>..] - ETA: 0s
# 45/46 [============================>.] - ETA: 0s
# 46/46 [==============================] - 1s 30ms/step
# Sklearn binary metrics:
# accuracy: 0.9310
# precision: 0.4849
# recall: 0.7689
# f1: 0.5947
# mcc: 0.5769
# roc_auc: 0.9512
# pr_auc: 0.6930
# log_loss: 0.1729
# brier_score: 0.0509
#
# Confusion matrix:
#  [[39647  2421]
#  [  685  2279]]
#
# Classification report:
#                precision    recall  f1-score   support
#
#            0     0.9830    0.9425    0.9623     42068
#            1     0.4849    0.7689    0.5947      2964
#
#     accuracy                         0.9310     45032
#    macro avg     0.7340    0.8557    0.7785     45032
# weighted avg     0.9502    0.9310    0.9381     45032
