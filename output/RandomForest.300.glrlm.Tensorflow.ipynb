# %%
# Import packages and modules
import numpy  as np
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow_decision_forests as tfdf

from sklearn.model_selection import train_test_split
# Out:
# 2026-07-04 08:55:47.575870: I tensorflow/core/util/port.cc:113] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2026-07-04 08:55:47.614173: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2026-07-04 08:55:53.612327: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
# Check the version of TensorFlow Decision Forests
print("Found TensorFlow Decision Forests v" + tfdf.__version__)
# Out:
# Found TensorFlow Decision Forests v1.9.1

# %%
datasetPath = 'dataset/firstorder/kernel5-radius5/dataset.csv'

# %%
# Parameters
datasetPath = "dataset/glrlm/kernel5-radius5/300.dataset.csv"

# %%
# train/validation/test = 70/10/20
dataset = pd.read_csv(datasetPath)

train_data, temp_data = train_test_split(dataset, test_size=0.3, random_state=42)
validation_data, test_data = train_test_split(temp_data, test_size=2/3, random_state=42)

# %%
from sklearn.utils.class_weight import compute_class_weight

# tinh class weight tren tap train
classes = np.array([0, 1])
weights = compute_class_weight(class_weight="balanced", classes=classes, y=train_data["label"])
class_weight = {0: weights[0], 1: weights[1]}

# gan sample_weight cho tung dong
train_data["sample_weight"] = train_data["label"].map(class_weight)
validation_data["sample_weight"] = validation_data["label"].map(class_weight)
test_data["sample_weight"] = test_data["label"].map(class_weight)

# Convert the dataset into a TensorFlow dataset.
train_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    train_data, label="label", weight="sample_weight"
)         
val_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    validation_data, label="label", weight="sample_weight"
)
test_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    test_data, label="label", weight="sample_weight"
)
# Out:
# 2026-07-04 08:56:05.850191: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:984] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2026-07-04 08:56:05.852005: W tensorflow/core/common_runtime/gpu/gpu_device.cc:2251] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...

# %%
import keras

# %%
# %%time

# Train a Random Forest model.
model = tfdf.keras.RandomForestModel()

# Add evaluation metrics
model.compile(
    metrics=["accuracy"]
)
model.fit(x=train_ds)

# # Train a Gradient Boosted Trees model.
# model = tfdf.keras.GradientBoostedTreesModel(num_trees=1500)
# model.fit(train_ds)
# Out:
# Use /tmp/tmpo4apobpl as temporary training directory
# Reading training dataset...
# Training dataset read in 0:00:03.411860. Found 235709 examples.
# Training model...
# [INFO 26-07-04 08:56:34.2096 UTC kernel.cc:1233] Loading model from path /tmp/tmpo4apobpl/model/ with prefix 40fa00ebd57f4811
# [INFO 26-07-04 08:56:35.6190 UTC decision_forest.cc:734] Model loaded with 300 root(s), 1209702 node(s), and 16 input feature(s).
# [INFO 26-07-04 08:56:35.6191 UTC abstract_model.cc:1362] Engine "RandomForestOptPred" built
# [INFO 26-07-04 08:56:35.6191 UTC kernel.cc:1061] Use fast generic engine
# Model trained in 0:00:26.386816
# Compiling model...
# Model compiled.
# CPU times: user 4min 42s, sys: 1.71 s, total: 4min 44s
# Wall time: 32.9 s

# %%
# Evaluate the model
evaluate = model.evaluate(val_ds, return_dict=True)
print()

for name, value in evaluate.items():
    print(f"{name}: {value:.4f}")
# Out:
# WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
#  1/34 [..............................] - ETA: 1:38 - loss: 0.0000e+00 - accuracy: 0.9320
#  3/34 [=>............................] - ETA: 0s - loss: 0.0000e+00 - accuracy: 0.9263
#  5/34 [===>..........................] - ETA: 0s - loss: 0.0000e+00 - accuracy: 0.9262
#  7/34 [=====>........................] - ETA: 0s - loss: 0.0000e+00 - accuracy: 0.9261
#  9/34 [======>.......................] - ETA: 0s - loss: 0.0000e+00 - accuracy: 0.9256
# 11/34 [========>.....................] - ETA: 0s - loss: 0.0000e+00 - accuracy: 0.9253
# 13/34 [==========>...................] - ETA: 0s - loss: 0.0000e+00 - accuracy: 0.9241
# 15/34 [============>.................] - ETA: 0s - loss: 0.0000e+00 - accuracy: 0.9237
# 17/34 [==============>...............] - ETA: 0s - loss: 0.0000e+00 - accuracy: 0.9246
# 19/34 [===============>..............] - ETA: 0s - loss: 0.0000e+00 - accuracy: 0.9237
# 21/34 [=================>............] - ETA: 0s - loss: 0.0000e+00 - accuracy: 0.9240
# 23/34 [===================>..........] - ETA: 0s - loss: 0.0000e+00 - accuracy: 0.9241
# 25/34 [=====================>........] - ETA: 0s - loss: 0.0000e+00 - accuracy: 0.9236
# 27/34 [======================>.......] - ETA: 0s - loss: 0.0000e+00 - accuracy: 0.9234
# 29/34 [========================>.....] - ETA: 0s - loss: 0.0000e+00 - accuracy: 0.9230
# 31/34 [==========================>...] - ETA: 0s - loss: 0.0000e+00 - accuracy: 0.9229
# 33/34 [============================>.] - ETA: 0s - loss: 0.0000e+00 - accuracy: 0.9225
# 34/34 [==============================] - 4s 31ms/step - loss: 0.0000e+00 - accuracy: 0.9227
# loss: 0.0000
# accuracy: 0.9227

# %%
# Model Summary
model.summary()
# Out:
# Model: "random_forest_model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
# =================================================================
# Total params: 1 (1.00 Byte)
# Trainable params: 0 (0.00 Byte)
# Non-trainable params: 1 (1.00 Byte)
# _________________________________________________________________
# Type: "RANDOM_FOREST"
# Task: CLASSIFICATION
# Label: "__LABEL"
#
# Input Features (16):
# 	GrayLevelNonUniformity
# 	GrayLevelNonUniformityNormalized
# 	GrayLevelVariance
# 	HighGrayLevelRunEmphasis
# 	LongRunEmphasis
# 	LongRunHighGrayLevelEmphasis
# 	LongRunLowGrayLevelEmphasis
# 	LowGrayLevelRunEmphasis
# 	RunEntropy
# 	RunLengthNonUniformity
# 	RunLengthNonUniformityNormalized
# 	RunPercentage
# 	RunVariance
# 	ShortRunEmphasis
# 	ShortRunHighGrayLevelEmphasis
# 	ShortRunLowGrayLevelEmphasis
#
# Trained with weights
#
# Variable Importance: INV_MEAN_MIN_DEPTH:
#     1.         "HighGrayLevelRunEmphasis"  0.196790 ################
#     2.     "LongRunHighGrayLevelEmphasis"  0.183808 ##############
#     3.    "ShortRunHighGrayLevelEmphasis"  0.147451 #########
#     4.          "LowGrayLevelRunEmphasis"  0.122054 #####
#     5.                       "RunEntropy"  0.118705 #####
#     6.     "ShortRunLowGrayLevelEmphasis"  0.118294 #####
#     7.           "GrayLevelNonUniformity"  0.112615 ####
#     8.      "LongRunLowGrayLevelEmphasis"  0.104109 ###
#     9. "GrayLevelNonUniformityNormalized"  0.093454 #
#    10.                "GrayLevelVariance"  0.088775
#    11.                 "ShortRunEmphasis"  0.087421
#    12.                      "RunVariance"  0.085946
#    13. "RunLengthNonUniformityNormalized"  0.085865
#    14.           "RunLengthNonUniformity"  0.083072
#    15.                    "RunPercentage"  0.082021
#    16.                  "LongRunEmphasis"  0.081619
#
# Variable Importance: NUM_AS_ROOT:
#     1.         "HighGrayLevelRunEmphasis" 98.000000 ################
#     2.     "LongRunHighGrayLevelEmphasis" 60.000000 #########
#     3.    "ShortRunHighGrayLevelEmphasis" 48.000000 #######
#     4.          "LowGrayLevelRunEmphasis" 47.000000 #######
#     5.     "ShortRunLowGrayLevelEmphasis" 22.000000 ###
#     6.      "LongRunLowGrayLevelEmphasis" 10.000000 #
#     7.                       "RunEntropy"  6.000000
#     8.           "GrayLevelNonUniformity"  5.000000
#     9. "GrayLevelNonUniformityNormalized"  2.000000
#    10.                  "LongRunEmphasis"  1.000000
#    11.                      "RunVariance"  1.000000
#
# Variable Importance: NUM_NODES:
#     1.           "GrayLevelNonUniformity" 48545.000000 ################
#     2.                       "RunEntropy" 47632.000000 ###############
#     3.     "LongRunHighGrayLevelEmphasis" 45682.000000 #############
#     4.                "GrayLevelVariance" 44938.000000 #############
#     5.     "ShortRunLowGrayLevelEmphasis" 40582.000000 #########
#     6. "GrayLevelNonUniformityNormalized" 40496.000000 #########
#     7.    "ShortRunHighGrayLevelEmphasis" 38386.000000 ########
#     8.      "LongRunLowGrayLevelEmphasis" 37250.000000 #######
#     9.         "HighGrayLevelRunEmphasis" 37107.000000 #######
#    10.          "LowGrayLevelRunEmphasis" 36843.000000 ######
#    11.                      "RunVariance" 35441.000000 #####
#    12. "RunLengthNonUniformityNormalized" 31732.000000 ##
#    13.                 "ShortRunEmphasis" 31463.000000 ##
#    14.                  "LongRunEmphasis" 30807.000000 ##
#    15.           "RunLengthNonUniformity" 29702.000000 #
#    16.                    "RunPercentage" 28095.000000
#
# Variable Importance: SUM_SCORE:
#     1.         "HighGrayLevelRunEmphasis" 6601924.247612 ################
#     2.     "LongRunHighGrayLevelEmphasis" 5662966.259325 #############
#     3.    "ShortRunHighGrayLevelEmphasis" 4563180.096271 ##########
#     4.          "LowGrayLevelRunEmphasis" 3352775.070220 #######
#     5.                       "RunEntropy" 2866388.436878 #####
#     6.     "ShortRunLowGrayLevelEmphasis" 2864318.998093 #####
#     7.           "GrayLevelNonUniformity" 2649811.122040 #####
#     8.      "LongRunLowGrayLevelEmphasis" 2058041.967866 ###
#     9. "GrayLevelNonUniformityNormalized" 1454963.134098 #
#    10.                "GrayLevelVariance" 1357445.367275 #
#    11.                      "RunVariance" 1101687.557108
#    12.                 "ShortRunEmphasis" 1051267.164373
#    13. "RunLengthNonUniformityNormalized" 1008595.864446
#    14.           "RunLengthNonUniformity" 852410.453071
#    15.                  "LongRunEmphasis" 841174.534594
#    16.                    "RunPercentage" 815032.556423
#
#
#
# Winner takes all: true
# Out-of-bag evaluation: accuracy:0.871328 logloss:0.462748
# Number of trees: 300
# Total number of nodes: 1209702
#
# Number of nodes by tree:
# Count: 300 Average: 4032.34 StdDev: 266.326
# Min: 3381 Max: 4865 Ignored: 0
# ----------------------------------------------
# [ 3381, 3455)  3   1.00%   1.00% #
# [ 3455, 3529)  4   1.33%   2.33% #
# [ 3529, 3603)  3   1.00%   3.33% #
# [ 3603, 3678)  8   2.67%   6.00% ##
# [ 3678, 3752) 23   7.67%  13.67% #######
# [ 3752, 3826) 32  10.67%  24.33% #########
# [ 3826, 3900) 33  11.00%  35.33% ##########
# [ 3900, 3975) 28   9.33%  44.67% ########
# [ 3975, 4049) 29   9.67%  54.33% #########
# [ 4049, 4123) 34  11.33%  65.67% ##########
# [ 4123, 4197) 26   8.67%  74.33% ########
# [ 4197, 4272) 19   6.33%  80.67% ######
# [ 4272, 4346) 13   4.33%  85.00% ####
# [ 4346, 4420) 17   5.67%  90.67% #####
# [ 4420, 4494) 16   5.33%  96.00% #####
# [ 4494, 4569)  6   2.00%  98.00% ##
# [ 4569, 4643)  0   0.00%  98.00%
# [ 4643, 4717)  3   1.00%  99.00% #
# [ 4717, 4791)  2   0.67%  99.67% #
# [ 4791, 4865]  1   0.33% 100.00%
#
# Depth by leafs:
# Count: 605001 Average: 13.0958 StdDev: 2.07529
# Min: 3 Max: 15 Ignored: 0
# ----------------------------------------------
# [  3,  4)      3   0.00%   0.00%
# [  4,  5)     86   0.01%   0.01%
# [  5,  6)    684   0.11%   0.13%
# [  6,  7)   2318   0.38%   0.51%
# [  7,  8)   5931   0.98%   1.49%
# [  8,  9)  12269   2.03%   3.52% #
# [  9, 10)  22052   3.64%   7.16% #
# [ 10, 11)  34930   5.77%  12.94% ##
# [ 11, 12)  51545   8.52%  21.46% ##
# [ 12, 13)  68706  11.36%  32.81% ###
# [ 13, 14)  85298  14.10%  46.91% ####
# [ 14, 15) 100157  16.55%  63.47% #####
# [ 15, 15] 221022  36.53% 100.00% ##########
#
# Number of training obs by leaf:
# Count: 605001 Average: 116.88 StdDev: 597.385
# Min: 5 Max: 24167 Ignored: 0
# ----------------------------------------------
# [     5,  1213) 595482  98.43%  98.43% ##########
# [  1213,  2421)   5319   0.88%  99.31%
# [  2421,  3629)   1753   0.29%  99.60%
# [  3629,  4837)    736   0.12%  99.72%
# [  4837,  6045)    431   0.07%  99.79%
# [  6045,  7253)    314   0.05%  99.84%
# [  7253,  8462)    215   0.04%  99.88%
# [  8462,  9670)    177   0.03%  99.91%
# [  9670, 10878)    134   0.02%  99.93%
# [ 10878, 12086)    109   0.02%  99.95%
# [ 12086, 13294)     81   0.01%  99.96%
# [ 13294, 14502)     54   0.01%  99.97%
# [ 14502, 15710)     52   0.01%  99.98%
# [ 15710, 16919)     41   0.01%  99.98%
# [ 16919, 18127)     40   0.01%  99.99%
# [ 18127, 19335)     21   0.00%  99.99%
# [ 19335, 20543)     21   0.00% 100.00%
# [ 20543, 21751)     12   0.00% 100.00%
# [ 21751, 22959)      6   0.00% 100.00%
# [ 22959, 24167]      3   0.00% 100.00%
#
# Attribute in nodes:
# 	48545 : GrayLevelNonUniformity [NUMERICAL]
# 	47632 : RunEntropy [NUMERICAL]
# 	45682 : LongRunHighGrayLevelEmphasis [NUMERICAL]
# 	44938 : GrayLevelVariance [NUMERICAL]
# 	40582 : ShortRunLowGrayLevelEmphasis [NUMERICAL]
# 	40496 : GrayLevelNonUniformityNormalized [NUMERICAL]
# 	38386 : ShortRunHighGrayLevelEmphasis [NUMERICAL]
# 	37250 : LongRunLowGrayLevelEmphasis [NUMERICAL]
# 	37107 : HighGrayLevelRunEmphasis [NUMERICAL]
# 	36843 : LowGrayLevelRunEmphasis [NUMERICAL]
# 	35441 : RunVariance [NUMERICAL]
# 	31732 : RunLengthNonUniformityNormalized [NUMERICAL]
# 	31463 : ShortRunEmphasis [NUMERICAL]
# 	30807 : LongRunEmphasis [NUMERICAL]
# 	29702 : RunLengthNonUniformity [NUMERICAL]
# 	28095 : RunPercentage [NUMERICAL]
#
# Attribute in nodes with depth <= 0:
# 	98 : HighGrayLevelRunEmphasis [NUMERICAL]
# 	60 : LongRunHighGrayLevelEmphasis [NUMERICAL]
# 	48 : ShortRunHighGrayLevelEmphasis [NUMERICAL]
# 	47 : LowGrayLevelRunEmphasis [NUMERICAL]
# 	22 : ShortRunLowGrayLevelEmphasis [NUMERICAL]
# 	10 : LongRunLowGrayLevelEmphasis [NUMERICAL]
# 	6 : RunEntropy [NUMERICAL]
# 	5 : GrayLevelNonUniformity [NUMERICAL]
# 	2 : GrayLevelNonUniformityNormalized [NUMERICAL]
# 	1 : RunVariance [NUMERICAL]
# 	1 : LongRunEmphasis [NUMERICAL]
#
# Attribute in nodes with depth <= 1:
# 	246 : HighGrayLevelRunEmphasis [NUMERICAL]
# 	224 : LongRunHighGrayLevelEmphasis [NUMERICAL]
# 	126 : ShortRunHighGrayLevelEmphasis [NUMERICAL]
# 	82 : LowGrayLevelRunEmphasis [NUMERICAL]
# 	76 : ShortRunLowGrayLevelEmphasis [NUMERICAL]
# 	49 : RunEntropy [NUMERICAL]
# 	35 : LongRunLowGrayLevelEmphasis [NUMERICAL]
# 	27 : GrayLevelNonUniformity [NUMERICAL]
# 	19 : GrayLevelNonUniformityNormalized [NUMERICAL]
# 	4 : ShortRunEmphasis [NUMERICAL]
# 	3 : RunVariance [NUMERICAL]
# 	3 : RunPercentage [NUMERICAL]
# 	2 : RunLengthNonUniformity [NUMERICAL]
# 	2 : GrayLevelVariance [NUMERICAL]
# 	1 : RunLengthNonUniformityNormalized [NUMERICAL]
# 	1 : LongRunEmphasis [NUMERICAL]
#
# Attribute in nodes with depth <= 2:
# 	445 : LongRunHighGrayLevelEmphasis [NUMERICAL]
# 	437 : HighGrayLevelRunEmphasis [NUMERICAL]
# 	273 : ShortRunHighGrayLevelEmphasis [NUMERICAL]
# 	163 : ShortRunLowGrayLevelEmphasis [NUMERICAL]
# 	157 : RunEntropy [NUMERICAL]
# 	146 : LowGrayLevelRunEmphasis [NUMERICAL]
# 	118 : GrayLevelNonUniformity [NUMERICAL]
# 	72 : LongRunLowGrayLevelEmphasis [NUMERICAL]
# 	61 : GrayLevelNonUniformityNormalized [NUMERICAL]
# 	59 : ShortRunEmphasis [NUMERICAL]
# 	36 : RunLengthNonUniformityNormalized [NUMERICAL]
# 	35 : RunVariance [NUMERICAL]
# 	30 : GrayLevelVariance [NUMERICAL]
# 	29 : RunLengthNonUniformity [NUMERICAL]
# 	20 : LongRunEmphasis [NUMERICAL]
# 	19 : RunPercentage [NUMERICAL]
#
# Attribute in nodes with depth <= 3:
# 	881 : LongRunHighGrayLevelEmphasis [NUMERICAL]
# 	645 : HighGrayLevelRunEmphasis [NUMERICAL]
# 	456 : ShortRunHighGrayLevelEmphasis [NUMERICAL]
# 	419 : RunEntropy [NUMERICAL]
# 	374 : ShortRunLowGrayLevelEmphasis [NUMERICAL]
# 	335 : GrayLevelNonUniformity [NUMERICAL]
# 	330 : LowGrayLevelRunEmphasis [NUMERICAL]
# 	240 : LongRunLowGrayLevelEmphasis [NUMERICAL]
# 	169 : GrayLevelNonUniformityNormalized [NUMERICAL]
# 	151 : ShortRunEmphasis [NUMERICAL]
# 	122 : RunLengthNonUniformityNormalized [NUMERICAL]
# 	110 : GrayLevelVariance [NUMERICAL]
# 	81 : RunVariance [NUMERICAL]
# 	69 : RunLengthNonUniformity [NUMERICAL]
# 	58 : RunPercentage [NUMERICAL]
# 	57 : LongRunEmphasis [NUMERICAL]
#
# Attribute in nodes with depth <= 5:
# 	2512 : LongRunHighGrayLevelEmphasis [NUMERICAL]
# 	1834 : RunEntropy [NUMERICAL]
# 	1524 : HighGrayLevelRunEmphasis [NUMERICAL]
# 	1508 : GrayLevelNonUniformity [NUMERICAL]
# 	1317 : ShortRunLowGrayLevelEmphasis [NUMERICAL]
# 	1278 : ShortRunHighGrayLevelEmphasis [NUMERICAL]
# 	1230 : LowGrayLevelRunEmphasis [NUMERICAL]
# 	967 : LongRunLowGrayLevelEmphasis [NUMERICAL]
# 	898 : GrayLevelNonUniformityNormalized [NUMERICAL]
# 	847 : GrayLevelVariance [NUMERICAL]
# 	835 : ShortRunEmphasis [NUMERICAL]
# 	817 : RunLengthNonUniformityNormalized [NUMERICAL]
# 	644 : RunVariance [NUMERICAL]
# 	597 : RunLengthNonUniformity [NUMERICAL]
# 	568 : LongRunEmphasis [NUMERICAL]
# 	561 : RunPercentage [NUMERICAL]
#
# Condition type in nodes:
# 	604701 : HigherCondition
# Condition type in nodes with depth <= 0:
# 	300 : HigherCondition
# Condition type in nodes with depth <= 1:
# 	900 : HigherCondition
# Condition type in nodes with depth <= 2:
# 	2100 : HigherCondition
# Condition type in nodes with depth <= 3:
# 	4497 : HigherCondition
# Condition type in nodes with depth <= 5:
# 	17937 : HigherCondition
# Node format: NOT_SET
#
# Training OOB:
# 	trees: 1, Out-of-bag evaluation: accuracy:0.831591 logloss:6.07008
# 	trees: 11, Out-of-bag evaluation: accuracy:0.845873 logloss:2.36389
# 	trees: 21, Out-of-bag evaluation: accuracy:0.8614 logloss:1.48952
# 	trees: 31, Out-of-bag evaluation: accuracy:0.866199 logloss:1.20218
# 	trees: 41, Out-of-bag evaluation: accuracy:0.866728 logloss:1.0175
# 	trees: 51, Out-of-bag evaluation: accuracy:0.86773 logloss:0.915163
# 	trees: 61, Out-of-bag evaluation: accuracy:0.869055 logloss:0.838867
# 	trees: 71, Out-of-bag evaluation: accuracy:0.869601 logloss:0.774014
# 	trees: 81, Out-of-bag evaluation: accuracy:0.869552 logloss:0.733486
# 	trees: 91, Out-of-bag evaluation: accuracy:0.869179 logloss:0.700752
# 	trees: 101, Out-of-bag evaluation: accuracy:0.869552 logloss:0.674379
# 	trees: 111, Out-of-bag evaluation: accuracy:0.870097 logloss:0.64729
# 	trees: 121, Out-of-bag evaluation: accuracy:0.870087 logloss:0.612704
# 	trees: 131, Out-of-bag evaluation: accuracy:0.870647 logloss:0.588246
# 	trees: 141, Out-of-bag evaluation: accuracy:0.870784 logloss:0.577415
# 	trees: 151, Out-of-bag evaluation: accuracy:0.8715 logloss:0.565516
# 	trees: 161, Out-of-bag evaluation: accuracy:0.870924 logloss:0.556707
# 	trees: 171, Out-of-bag evaluation: accuracy:0.871168 logloss:0.546453
# 	trees: 181, Out-of-bag evaluation: accuracy:0.87123 logloss:0.537001
# 	trees: 191, Out-of-bag evaluation: accuracy:0.871207 logloss:0.531547
# 	trees: 201, Out-of-bag evaluation: accuracy:0.871559 logloss:0.524466
# 	trees: 211, Out-of-bag evaluation: accuracy:0.871522 logloss:0.518802
# 	trees: 221, Out-of-bag evaluation: accuracy:0.871644 logloss:0.510758
# 	trees: 231, Out-of-bag evaluation: accuracy:0.871185 logloss:0.505011
# 	trees: 241, Out-of-bag evaluation: accuracy:0.87118 logloss:0.49965
# 	trees: 251, Out-of-bag evaluation: accuracy:0.870635 logloss:0.488931
# 	trees: 261, Out-of-bag evaluation: accuracy:0.871043 logloss:0.482295
# 	trees: 271, Out-of-bag evaluation: accuracy:0.871131 logloss:0.475025
# 	trees: 281, Out-of-bag evaluation: accuracy:0.871067 logloss:0.469602
# 	trees: 291, Out-of-bag evaluation: accuracy:0.871202 logloss:0.466825
# 	trees: 300, Out-of-bag evaluation: accuracy:0.871328 logloss:0.462748

# %%
# Model features
model.make_inspector().features()
# Out:
# ["GrayLevelNonUniformity" (1; #0),
#  "GrayLevelNonUniformityNormalized" (1; #1),
#  "GrayLevelVariance" (1; #2),
#  "HighGrayLevelRunEmphasis" (1; #3),
#  "LongRunEmphasis" (1; #4),
#  "LongRunHighGrayLevelEmphasis" (1; #5),
#  "LongRunLowGrayLevelEmphasis" (1; #6),
#  "LowGrayLevelRunEmphasis" (1; #7),
#  "RunEntropy" (1; #8),
#  "RunLengthNonUniformity" (1; #9),
#  "RunLengthNonUniformityNormalized" (1; #10),
#  "RunPercentage" (1; #11),
#  "RunVariance" (1; #12),
#  "ShortRunEmphasis" (1; #13),
#  "ShortRunHighGrayLevelEmphasis" (1; #14),
#  "ShortRunLowGrayLevelEmphasis" (1; #15)]

# %%
# Feature importance
model.make_inspector().variable_importances()
# Out:
# {'INV_MEAN_MIN_DEPTH': [("HighGrayLevelRunEmphasis" (1; #3),
#    0.19678966384458838),
#   ("LongRunHighGrayLevelEmphasis" (1; #5), 0.18380788726255462),
#   ("ShortRunHighGrayLevelEmphasis" (1; #14), 0.14745099841439638),
#   ("LowGrayLevelRunEmphasis" (1; #7), 0.12205411981769078),
#   ("RunEntropy" (1; #8), 0.11870523291278796),
#   ("ShortRunLowGrayLevelEmphasis" (1; #15), 0.11829377589080801),
#   ("GrayLevelNonUniformity" (1; #0), 0.11261471017521475),
#   ("LongRunLowGrayLevelEmphasis" (1; #6), 0.10410931919008112),
#   ("GrayLevelNonUniformityNormalized" (1; #1), 0.0934542213949373),
#   ("GrayLevelVariance" (1; #2), 0.08877501027864433),
#   ("ShortRunEmphasis" (1; #13), 0.08742054532557468),
#   ("RunVariance" (1; #12), 0.08594569667349697),
#   ("RunLengthNonUniformityNormalized" (1; #10), 0.08586469473970246),
#   ("RunLengthNonUniformity" (1; #9), 0.08307200012922034),
#   ("RunPercentage" (1; #11), 0.08202109310908241),
#   ("LongRunEmphasis" (1; #4), 0.08161948106082345)],
#  'SUM_SCORE': [("HighGrayLevelRunEmphasis" (1; #3), 6601924.247611685),
#   ("LongRunHighGrayLevelEmphasis" (1; #5), 5662966.259324673),
#   ("ShortRunHighGrayLevelEmphasis" (1; #14), 4563180.096270512),
#   ("LowGrayLevelRunEmphasis" (1; #7), 3352775.070220181),
#   ("RunEntropy" (1; #8), 2866388.4368782365),
#   ("ShortRunLowGrayLevelEmphasis" (1; #15), 2864318.998093403),
#   ("GrayLevelNonUniformity" (1; #0), 2649811.1220396063),
#   ("LongRunLowGrayLevelEmphasis" (1; #6), 2058041.967865605),
#   ("GrayLevelNonUniformityNormalized" (1; #1), 1454963.134097756),
#   ("GrayLevelVariance" (1; #2), 1357445.3672754082),
#   ("RunVariance" (1; #12), 1101687.5571082602),
#   ("ShortRunEmphasis" (1; #13), 1051267.1643731995),
#   ("RunLengthNonUniformityNormalized" (1; #10), 1008595.8644459782),
#   ("RunLengthNonUniformity" (1; #9), 852410.4530707829),
#   ("LongRunEmphasis" (1; #4), 841174.534593753),
#   ("RunPercentage" (1; #11), 815032.5564230472)],
#  'NUM_AS_ROOT': [("HighGrayLevelRunEmphasis" (1; #3), 98.0),
#   ("LongRunHighGrayLevelEmphasis" (1; #5), 60.0),
#   ("ShortRunHighGrayLevelEmphasis" (1; #14), 48.0),
#   ("LowGrayLevelRunEmphasis" (1; #7), 47.0),
#   ("ShortRunLowGrayLevelEmphasis" (1; #15), 22.0),
#   ("LongRunLowGrayLevelEmphasis" (1; #6), 10.0),
#   ("RunEntropy" (1; #8), 6.0),
#   ("GrayLevelNonUniformity" (1; #0), 5.0),
#   ("GrayLevelNonUniformityNormalized" (1; #1), 2.0),
#   ("LongRunEmphasis" (1; #4), 1.0),
#   ("RunVariance" (1; #12), 1.0)],
#  'NUM_NODES': [("GrayLevelNonUniformity" (1; #0), 48545.0),
#   ("RunEntropy" (1; #8), 47632.0),
#   ("LongRunHighGrayLevelEmphasis" (1; #5), 45682.0),
#   ("GrayLevelVariance" (1; #2), 44938.0),
#   ("ShortRunLowGrayLevelEmphasis" (1; #15), 40582.0),
#   ("GrayLevelNonUniformityNormalized" (1; #1), 40496.0),
#   ("ShortRunHighGrayLevelEmphasis" (1; #14), 38386.0),
#   ("LongRunLowGrayLevelEmphasis" (1; #6), 37250.0),
#   ("HighGrayLevelRunEmphasis" (1; #3), 37107.0),
#   ("LowGrayLevelRunEmphasis" (1; #7), 36843.0),
#   ("RunVariance" (1; #12), 35441.0),
#   ("RunLengthNonUniformityNormalized" (1; #10), 31732.0),
#   ("ShortRunEmphasis" (1; #13), 31463.0),
#   ("LongRunEmphasis" (1; #4), 30807.0),
#   ("RunLengthNonUniformity" (1; #9), 29702.0),
#   ("RunPercentage" (1; #11), 28095.0)]}

# %%
# Model self evaluation
model.make_inspector().evaluation()
# Out:
# Evaluation(num_examples=235709, accuracy=0.8713279115085524, loss=0.46274833857825437, rmse=None, ndcg=None, aucs=None, auuc=None, qini=None)

# %%
logs = model.make_inspector().training_logs()

plt.figure(figsize=(12, 4))
plt.subplot(1, 2, 1)
plt.plot([log.num_trees for log in logs], [log.evaluation.accuracy for log in logs])
plt.xlabel("Number of trees")
plt.ylabel("Accuracy (out-of-bag)")
plt.subplot(1, 2, 2)
plt.plot([log.num_trees for log in logs], [log.evaluation.loss for log in logs])
plt.xlabel("Number of trees")
plt.ylabel("Logloss (out-of-bag)")
plt.show()

# %% [markdown]
# Calculate the score of our hold-out validation dataset

# %%
predictions = model.predict(val_ds)
y_true      = validation_data["label"]

from sklearn.metrics import roc_auc_score
ROC_AUC = roc_auc_score(y_true, predictions)
print("The ROC AUC score is %.5f" % ROC_AUC )
# Out:
#  1/34 [..............................] - ETA: 3s
#  3/34 [=>............................] - ETA: 0s
#  5/34 [===>..........................] - ETA: 0s
#  7/34 [=====>........................] - ETA: 0s
#  9/34 [======>.......................] - ETA: 0s
# 11/34 [========>.....................] - ETA: 0s
# 13/34 [==========>...................] - ETA: 0s
# 15/34 [============>.................] - ETA: 0s
# 17/34 [==============>...............] - ETA: 0s
# 19/34 [===============>..............] - ETA: 0s
# 21/34 [=================>............] - ETA: 0s
# 23/34 [===================>..........] - ETA: 0s
# 25/34 [=====================>........] - ETA: 0s
# 27/34 [======================>.......] - ETA: 0s
# 29/34 [========================>.....] - ETA: 0s
# 31/34 [==========================>...] - ETA: 0s
# 33/34 [============================>.] - ETA: 0s
# 34/34 [==============================] - 1s 31ms/step
# The ROC AUC score is 0.95435

# %%
# Compute binary classification metrics with sklearn
import numpy as np
from sklearn.metrics import (
    accuracy_score,
    precision_score,
    recall_score,
    f1_score,
    roc_auc_score,
    average_precision_score,
    confusion_matrix,
    classification_report,
    matthews_corrcoef,
    log_loss,
    brier_score_loss,
)

# Get predictions (probabilities or class labels)
preds = model.predict(test_ds)
# If model outputs probabilities, convert to labels by threshold 0.5
if preds.ndim == 2:
    # For TFDF classification, preds may be class probabilities with shape (N, 2)
    if preds.shape[1] == 2:
        pos_probs = preds[:, 1]
    else:
        # If single-probability column (positive class)
        pos_probs = preds[:, -1]
    y_pred = (pos_probs >= 0.5).astype(int)
else:
    # Already class labels
    y_pred = preds.astype(int)
    pos_probs = None

# Ground truth labels (must be 0/1 integers)
y_true = test_data["label"].astype(int).to_numpy()

# Core metrics
metrics = {}
metrics["accuracy"] = accuracy_score(y_true, y_pred)
metrics["precision"] = precision_score(y_true, y_pred, zero_division=0)
metrics["recall"] = recall_score(y_true, y_pred, zero_division=0)
metrics["f1"] = f1_score(y_true, y_pred, zero_division=0)
metrics["mcc"] = matthews_corrcoef(y_true, y_pred)

# Probabilistic metrics (only if we have probabilities)
if pos_probs is not None:
    metrics["roc_auc"] = roc_auc_score(y_true, pos_probs)
    metrics["pr_auc"] = average_precision_score(y_true, pos_probs)
    metrics["log_loss"] = log_loss(y_true, pos_probs, labels=[0,1])
    metrics["brier_score"] = brier_score_loss(y_true, pos_probs)

# Confusion matrix and detailed report
cm = confusion_matrix(y_true, y_pred, labels=[0,1])
report = classification_report(y_true, y_pred, digits=4)

print("Sklearn binary metrics:")
for k, v in metrics.items():
    print(f"{k}: {v:.4f}")
print("\nConfusion matrix:\n", cm)
print("\nClassification report:\n", report)
# Out:
#  1/68 [..............................] - ETA: 6s
#  3/68 [>.............................] - ETA: 1s
#  5/68 [=>............................] - ETA: 1s
#  7/68 [==>...........................] - ETA: 1s
#  9/68 [==>...........................] - ETA: 1s
# 11/68 [===>..........................] - ETA: 1s
# 13/68 [====>.........................] - ETA: 1s
# 15/68 [=====>........................] - ETA: 1s
# 17/68 [======>.......................] - ETA: 1s
# 19/68 [=======>......................] - ETA: 1s
# 21/68 [========>.....................] - ETA: 1s
# 23/68 [=========>....................] - ETA: 1s
# 25/68 [==========>...................] - ETA: 1s
# 27/68 [==========>...................] - ETA: 1s
# 29/68 [===========>..................] - ETA: 1s
# 31/68 [============>.................] - ETA: 1s
# 33/68 [=============>................] - ETA: 1s
# 35/68 [==============>...............] - ETA: 1s
# 37/68 [===============>..............] - ETA: 0s
# 39/68 [================>.............] - ETA: 0s
# 41/68 [=================>............] - ETA: 0s
# 43/68 [=================>............] - ETA: 0s
# 45/68 [==================>...........] - ETA: 0s
# 47/68 [===================>..........] - ETA: 0s
# 49/68 [====================>.........] - ETA: 0s
# 51/68 [=====================>........] - ETA: 0s
# 53/68 [======================>.......] - ETA: 0s
# 55/68 [=======================>......] - ETA: 0s
# 57/68 [========================>.....] - ETA: 0s
# 59/68 [=========================>....] - ETA: 0s
# 61/68 [=========================>....] - ETA: 0s
# 63/68 [==========================>...] - ETA: 0s
# 65/68 [===========================>..] - ETA: 0s
# 67/68 [============================>.] - ETA: 0s
# 68/68 [==============================] - 2s 31ms/step
# Sklearn binary metrics:
# accuracy: 0.9208
# precision: 0.4194
# recall: 0.8048
# f1: 0.5514
# mcc: 0.5456
# roc_auc: 0.9518
# pr_auc: 0.6723
# log_loss: 0.1926
# brier_score: 0.0576
#
# Confusion matrix:
#  [[58735  4538]
#  [  795  3278]]
#
# Classification report:
#                precision    recall  f1-score   support
#
#            0     0.9866    0.9283    0.9566     63273
#            1     0.4194    0.8048    0.5514      4073
#
#     accuracy                         0.9208     67346
#    macro avg     0.7030    0.8665    0.7540     67346
# weighted avg     0.9523    0.9208    0.9321     67346
