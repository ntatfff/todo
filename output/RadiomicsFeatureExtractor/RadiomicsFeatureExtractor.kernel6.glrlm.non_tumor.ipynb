# %% [markdown]
# <a href="https://colab.research.google.com/github/ntatfff/todo/blob/202411241258/ColabRadiomicsFeatureExtractor.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
kernel = 1
className = 'firstorder'

# %%
# Parameters
kernel = 6
className = "glrlm"

# %%
import radiomics
import numpy as np
import SimpleITK as sitk
import radiomics.featureextractor
import os
import six
from os import path
import pandas as pd

def featureExtractor(fileId):
  imagePath = './dataset/BraTS2021_Training_Data/%s/%s_flair.nii.gz' % (fileId, fileId)
  image = sitk.ReadImage(imagePath)
  maskPath ='./dataset/BraTS2021_Training_Data/%s/%s_kernel%s_non_tumor.nii.gz' % (fileId, fileId, kernel)
  mask = sitk.ReadImage(maskPath)

  settings = {}
  settings['kernelRadius'] = kernel
  settings['maskedKernel'] = False
  settings['voxelBatch'] = 1000
  extractor = radiomics.featureextractor.RadiomicsFeatureExtractor(**settings)
  extractor.disableAllFeatures()
  extractor.enableFeatureClassByName(className)

  featureMap = extractor.execute(image, mask, voxelBased=True)

  for featureName, featureValue in six.iteritems(featureMap):
    if isinstance(featureValue, sitk.Image):
      fileFolder = './dataset/%s/kernel%s/non_tumor/%s' % (className, kernel, fileId)
      if path.exists(fileFolder) == False:
        os.makedirs(fileFolder, exist_ok=True)
      sitk.WriteImage(featureValue, '%s/%s.nrrd' % (fileFolder, featureName))
      print('Computed %s, stored as "%s/%s.nrrd"' % (featureName, fileFolder, featureName))
    # else:
    #   print('%s: %s' % (featureName, featureValue))

monitorFilePath = './dataset/%s/kernel%s/non_tumor.monitor.csv' % (className, kernel)
monitor = pd.read_csv(monitorFilePath, index_col='no')
for i, row in monitor.iterrows():
  if row['done'] != 0:
    continue
  fileId = row['file']
  print('Starting %s' % (fileId))
  featureExtractor(fileId)
  monitor.at[i, 'done'] = 1
  monitor.to_csv(monitorFilePath)
# Out:
# Starting BraTS2021_00002
# Computed original_glrlm_GrayLevelNonUniformity, stored as "./dataset/glrlm/kernel6/non_tumor/BraTS2021_00002/original_glrlm_GrayLevelNonUniformity.nrrd"
# Computed original_glrlm_GrayLevelNonUniformityNormalized, stored as "./dataset/glrlm/kernel6/non_tumor/BraTS2021_00002/original_glrlm_GrayLevelNonUniformityNormalized.nrrd"
# Computed original_glrlm_GrayLevelVariance, stored as "./dataset/glrlm/kernel6/non_tumor/BraTS2021_00002/original_glrlm_GrayLevelVariance.nrrd"
# Computed original_glrlm_HighGrayLevelRunEmphasis, stored as "./dataset/glrlm/kernel6/non_tumor/BraTS2021_00002/original_glrlm_HighGrayLevelRunEmphasis.nrrd"
# Computed original_glrlm_LongRunEmphasis, stored as "./dataset/glrlm/kernel6/non_tumor/BraTS2021_00002/original_glrlm_LongRunEmphasis.nrrd"
# Computed original_glrlm_LongRunHighGrayLevelEmphasis, stored as "./dataset/glrlm/kernel6/non_tumor/BraTS2021_00002/original_glrlm_LongRunHighGrayLevelEmphasis.nrrd"
# Computed original_glrlm_LongRunLowGrayLevelEmphasis, stored as "./dataset/glrlm/kernel6/non_tumor/BraTS2021_00002/original_glrlm_LongRunLowGrayLevelEmphasis.nrrd"
# Computed original_glrlm_LowGrayLevelRunEmphasis, stored as "./dataset/glrlm/kernel6/non_tumor/BraTS2021_00002/original_glrlm_LowGrayLevelRunEmphasis.nrrd"
# Computed original_glrlm_RunEntropy, stored as "./dataset/glrlm/kernel6/non_tumor/BraTS2021_00002/original_glrlm_RunEntropy.nrrd"
# Computed original_glrlm_RunLengthNonUniformity, stored as "./dataset/glrlm/kernel6/non_tumor/BraTS2021_00002/original_glrlm_RunLengthNonUniformity.nrrd"
# Computed original_glrlm_RunLengthNonUniformityNormalized, stored as "./dataset/glrlm/kernel6/non_tumor/BraTS2021_00002/original_glrlm_RunLengthNonUniformityNormalized.nrrd"
# Computed original_glrlm_RunPercentage, stored as "./dataset/glrlm/kernel6/non_tumor/BraTS2021_00002/original_glrlm_RunPercentage.nrrd"
# Computed original_glrlm_RunVariance, stored as "./dataset/glrlm/kernel6/non_tumor/BraTS2021_00002/original_glrlm_RunVariance.nrrd"
# Computed original_glrlm_ShortRunEmphasis, stored as "./dataset/glrlm/kernel6/non_tumor/BraTS2021_00002/original_glrlm_ShortRunEmphasis.nrrd"
# Computed original_glrlm_ShortRunHighGrayLevelEmphasis, stored as "./dataset/glrlm/kernel6/non_tumor/BraTS2021_00002/original_glrlm_ShortRunHighGrayLevelEmphasis.nrrd"
# Computed original_glrlm_ShortRunLowGrayLevelEmphasis, stored as "./dataset/glrlm/kernel6/non_tumor/BraTS2021_00002/original_glrlm_ShortRunLowGrayLevelEmphasis.nrrd"
