# %%
# Import packages and modules
import numpy  as np
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow_decision_forests as tfdf

from sklearn.model_selection import train_test_split
# Out:
# 2026-08-12 05:41:05.019174: I tensorflow/core/util/port.cc:113] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2026-08-12 05:41:05.334957: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2026-08-12 05:41:09.724403: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
# Check the version of TensorFlow Decision Forests
print("Found TensorFlow Decision Forests v" + tfdf.__version__)
# Out:
# Found TensorFlow Decision Forests v1.9.1

# %%
datasetPath = 'dataset/firstorder/kernel5-radius5/dataset.csv'

# %%
# Parameters
datasetPath = "dataset/glrlm/kernel6/1.dataset.csv"

# %%
# train/validation/test = 70/10/20
dataset = pd.read_csv(datasetPath)

train_data, temp_data = train_test_split(dataset, test_size=0.3, random_state=42)
validation_data, test_data = train_test_split(temp_data, test_size=2/3, random_state=42)

# %%
from sklearn.utils.class_weight import compute_class_weight

# tinh class weight tren tap train
classes = np.array([0, 1])
weights = compute_class_weight(class_weight="balanced", classes=classes, y=train_data["label"])
class_weight = {0: weights[0], 1: weights[1]}

# gan sample_weight cho tung dong
train_data["sample_weight"] = train_data["label"].map(class_weight)
validation_data["sample_weight"] = validation_data["label"].map(class_weight)
test_data["sample_weight"] = test_data["label"].map(class_weight)

# Convert the dataset into a TensorFlow dataset.
train_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    train_data, label="label", weight="sample_weight"
)         
val_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    validation_data, label="label", weight="sample_weight"
)
test_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    test_data, label="label", weight="sample_weight"
)
# Out:
# 2026-08-12 05:41:21.730425: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:984] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2026-08-12 05:41:21.731834: W tensorflow/core/common_runtime/gpu/gpu_device.cc:2251] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...

# %%
import keras

# %%
# %%time

# Train a Gradient Boosted Trees model.
model = tfdf.keras.GradientBoostedTreesModel()

# Add evaluation metrics
model.compile(
    metrics=["accuracy"]
)
model.fit(x=train_ds)

# # Train a Gradient Boosted Trees model.
# model = tfdf.keras.GradientBoostedTreesModel(num_trees=1500)
# model.fit(train_ds)
# Out:
# Use /tmp/tmpydu159wr as temporary training directory
# Reading training dataset...
# [WARNING 26-08-12 05:41:21.8632 UTC gradient_boosted_trees.cc:1840] "goss_alpha" set but "sampling_method" not equal to "GOSS".
# [WARNING 26-08-12 05:41:21.8634 UTC gradient_boosted_trees.cc:1851] "goss_beta" set but "sampling_method" not equal to "GOSS".
# [WARNING 26-08-12 05:41:21.8634 UTC gradient_boosted_trees.cc:1865] "selective_gradient_boosting_ratio" set but "sampling_method" not equal to "SELGB".
# Training dataset read in 0:00:02.410495. Found 450 examples.
# Training model...
# Model trained in -1 day, 23:59:59.882987
# Compiling model...
# [INFO 26-08-12 05:41:24.1817 UTC kernel.cc:1233] Loading model from path /tmp/tmpydu159wr/model/ with prefix 9ae353bd582b4ed2
# [INFO 26-08-12 05:41:24.1849 UTC quick_scorer_extended.cc:911] The binary was compiled without AVX2 support, but your CPU supports it. Enable it for faster model inference.
# [INFO 26-08-12 05:41:24.1850 UTC abstract_model.cc:1362] Engine "GradientBoostedTreesQuickScorerExtended" built
# [INFO 26-08-12 05:41:24.1850 UTC kernel.cc:1061] Use fast generic engine
# Model compiled.
# CPU times: user 5.61 s, sys: 530 ms, total: 6.14 s
# Wall time: 8.46 s

# %%
# Evaluate the model
evaluate = model.evaluate(val_ds, return_dict=True)
print()

for name, value in evaluate.items():
    print(f"{name}: {value:.4f}")
# Out:
# WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 1/1 [==============================] - ETA: 0s - loss: 0.0000e+00 - accuracy: 0.9375
# 1/1 [==============================] - 3s 3s/step - loss: 0.0000e+00 - accuracy: 0.9375
# loss: 0.0000
# accuracy: 0.9375

# %%
# Model Summary
model.summary()
# Out:
# Model: "gradient_boosted_trees_model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
# =================================================================
# Total params: 1 (1.00 Byte)
# Trainable params: 0 (0.00 Byte)
# Non-trainable params: 1 (1.00 Byte)
# _________________________________________________________________
# Type: "GRADIENT_BOOSTED_TREES"
# Task: CLASSIFICATION
# Label: "__LABEL"
#
# Input Features (16):
# 	GrayLevelNonUniformity
# 	GrayLevelNonUniformityNormalized
# 	GrayLevelVariance
# 	HighGrayLevelRunEmphasis
# 	LongRunEmphasis
# 	LongRunHighGrayLevelEmphasis
# 	LongRunLowGrayLevelEmphasis
# 	LowGrayLevelRunEmphasis
# 	RunEntropy
# 	RunLengthNonUniformity
# 	RunLengthNonUniformityNormalized
# 	RunPercentage
# 	RunVariance
# 	ShortRunEmphasis
# 	ShortRunHighGrayLevelEmphasis
# 	ShortRunLowGrayLevelEmphasis
#
# Trained with weights
#
# Variable Importance: INV_MEAN_MIN_DEPTH:
#     1.     "LongRunHighGrayLevelEmphasis"  0.591437 ################
#     2.          "LowGrayLevelRunEmphasis"  0.228276 #
#     3.         "HighGrayLevelRunEmphasis"  0.224179 #
#     4.    "ShortRunHighGrayLevelEmphasis"  0.215852 #
#     5.                       "RunEntropy"  0.213311
#     6. "GrayLevelNonUniformityNormalized"  0.207895
#     7.     "ShortRunLowGrayLevelEmphasis"  0.205592
#     8.           "GrayLevelNonUniformity"  0.204414
#     9.                "GrayLevelVariance"  0.200998
#    10.      "LongRunLowGrayLevelEmphasis"  0.194801
#    11. "RunLengthNonUniformityNormalized"  0.194750
#    12.                 "ShortRunEmphasis"  0.193364
#    13.                      "RunVariance"  0.191430
#    14.                  "LongRunEmphasis"  0.190782
#    15.           "RunLengthNonUniformity"  0.190227
#    16.                    "RunPercentage"  0.188378
#
# Variable Importance: NUM_AS_ROOT:
#     1. "LongRunHighGrayLevelEmphasis" 58.000000 ################
#     2.      "LowGrayLevelRunEmphasis"  7.000000 #
#     3.     "HighGrayLevelRunEmphasis"  5.000000
#     4. "ShortRunLowGrayLevelEmphasis"  2.000000
#
# Variable Importance: NUM_NODES:
#     1.     "LongRunHighGrayLevelEmphasis" 231.000000 ################
#     2.                       "RunEntropy" 144.000000 #########
#     3.          "LowGrayLevelRunEmphasis" 101.000000 ######
#     4. "GrayLevelNonUniformityNormalized" 87.000000 #####
#     5.                "GrayLevelVariance" 85.000000 #####
#     6.    "ShortRunHighGrayLevelEmphasis" 69.000000 ####
#     7.           "GrayLevelNonUniformity" 67.000000 ###
#     8.     "ShortRunLowGrayLevelEmphasis" 60.000000 ###
#     9.         "HighGrayLevelRunEmphasis" 57.000000 ###
#    10.      "LongRunLowGrayLevelEmphasis" 55.000000 ##
#    11.                 "ShortRunEmphasis" 40.000000 #
#    12. "RunLengthNonUniformityNormalized" 38.000000 #
#    13.                      "RunVariance" 24.000000
#    14.           "RunLengthNonUniformity" 18.000000
#    15.                    "RunPercentage" 16.000000
#    16.                  "LongRunEmphasis" 15.000000
#
# Variable Importance: SUM_SCORE:
#     1.     "LongRunHighGrayLevelEmphasis" 427.030466 ################
#     2.           "GrayLevelNonUniformity" 23.722522
#     3.                       "RunEntropy" 22.971382
#     4. "GrayLevelNonUniformityNormalized" 16.254995
#     5.    "ShortRunHighGrayLevelEmphasis"  7.930403
#     6.                      "RunVariance"  7.570695
#     7.                 "ShortRunEmphasis"  7.383798
#     8. "RunLengthNonUniformityNormalized"  7.282584
#     9.         "HighGrayLevelRunEmphasis"  6.251668
#    10.          "LowGrayLevelRunEmphasis"  5.716479
#    11.     "ShortRunLowGrayLevelEmphasis"  5.478108
#    12.      "LongRunLowGrayLevelEmphasis"  4.254118
#    13.                  "LongRunEmphasis"  4.046548
#    14.                    "RunPercentage"  2.229579
#    15.                "GrayLevelVariance"  2.156243
#    16.           "RunLengthNonUniformity"  1.818072
#
#
#
# Loss: BINOMIAL_LOG_LIKELIHOOD
# Validation loss value: 0.0465713
# Number of trees per iteration: 1
# Node format: NOT_SET
# Number of trees: 72
# Total number of nodes: 2286
#
# Number of nodes by tree:
# Count: 72 Average: 31.75 StdDev: 5.83512
# Min: 21 Max: 43 Ignored: 0
# ----------------------------------------------
# [ 21, 22)  2   2.78%   2.78% ##
# [ 22, 23)  0   0.00%   2.78%
# [ 23, 24)  6   8.33%  11.11% ######
# [ 24, 25)  0   0.00%  11.11%
# [ 25, 26)  9  12.50%  23.61% #########
# [ 26, 27)  0   0.00%  23.61%
# [ 27, 29)  4   5.56%  29.17% ####
# [ 29, 30)  8  11.11%  40.28% ########
# [ 30, 31)  0   0.00%  40.28%
# [ 31, 32)  5   6.94%  47.22% #####
# [ 32, 33)  0   0.00%  47.22%
# [ 33, 34) 10  13.89%  61.11% ##########
# [ 34, 35)  0   0.00%  61.11%
# [ 35, 37)  9  12.50%  73.61% #########
# [ 37, 38)  8  11.11%  84.72% ########
# [ 38, 39)  0   0.00%  84.72%
# [ 39, 40)  6   8.33%  93.06% ######
# [ 40, 41)  0   0.00%  93.06%
# [ 41, 42)  2   2.78%  95.83% ##
# [ 42, 43]  3   4.17% 100.00% ###
#
# Depth by leafs:
# Count: 1179 Average: 4.40712 StdDev: 0.918466
# Min: 2 Max: 5 Ignored: 0
# ----------------------------------------------
# [ 2, 3)  71   6.02%   6.02% #
# [ 3, 4) 142  12.04%  18.07% ##
# [ 4, 5) 202  17.13%  35.20% ###
# [ 5, 5] 764  64.80% 100.00% ##########
#
# Number of training obs by leaf:
# Count: 1179 Average: 24.855 StdDev: 49.5946
# Min: 5 Max: 327 Ignored: 0
# ----------------------------------------------
# [   5,  21) 929  78.80%  78.80% ##########
# [  21,  37) 103   8.74%  87.53% #
# [  37,  53)  24   2.04%  89.57%
# [  53,  69)  24   2.04%  91.60%
# [  69,  85)   8   0.68%  92.28%
# [  85, 101)   9   0.76%  93.04%
# [ 101, 118)  11   0.93%  93.98%
# [ 118, 134)   4   0.34%  94.32%
# [ 134, 150)  17   1.44%  95.76%
# [ 150, 166)   2   0.17%  95.93%
# [ 166, 182)   1   0.08%  96.01%
# [ 182, 198)   5   0.42%  96.44%
# [ 198, 214)   7   0.59%  97.03%
# [ 214, 231)  12   1.02%  98.05%
# [ 231, 247)   8   0.68%  98.73%
# [ 247, 263)   6   0.51%  99.24%
# [ 263, 279)   4   0.34%  99.58%
# [ 279, 295)   3   0.25%  99.83%
# [ 295, 311)   1   0.08%  99.92%
# [ 311, 327]   1   0.08% 100.00%
#
# Attribute in nodes:
# 	231 : LongRunHighGrayLevelEmphasis [NUMERICAL]
# 	144 : RunEntropy [NUMERICAL]
# 	101 : LowGrayLevelRunEmphasis [NUMERICAL]
# 	87 : GrayLevelNonUniformityNormalized [NUMERICAL]
# 	85 : GrayLevelVariance [NUMERICAL]
# 	69 : ShortRunHighGrayLevelEmphasis [NUMERICAL]
# 	67 : GrayLevelNonUniformity [NUMERICAL]
# 	60 : ShortRunLowGrayLevelEmphasis [NUMERICAL]
# 	57 : HighGrayLevelRunEmphasis [NUMERICAL]
# 	55 : LongRunLowGrayLevelEmphasis [NUMERICAL]
# 	40 : ShortRunEmphasis [NUMERICAL]
# 	38 : RunLengthNonUniformityNormalized [NUMERICAL]
# 	24 : RunVariance [NUMERICAL]
# 	18 : RunLengthNonUniformity [NUMERICAL]
# 	16 : RunPercentage [NUMERICAL]
# 	15 : LongRunEmphasis [NUMERICAL]
#
# Attribute in nodes with depth <= 0:
# 	58 : LongRunHighGrayLevelEmphasis [NUMERICAL]
# 	7 : LowGrayLevelRunEmphasis [NUMERICAL]
# 	5 : HighGrayLevelRunEmphasis [NUMERICAL]
# 	2 : ShortRunLowGrayLevelEmphasis [NUMERICAL]
#
# Attribute in nodes with depth <= 1:
# 	90 : LongRunHighGrayLevelEmphasis [NUMERICAL]
# 	32 : LowGrayLevelRunEmphasis [NUMERICAL]
# 	26 : HighGrayLevelRunEmphasis [NUMERICAL]
# 	15 : ShortRunHighGrayLevelEmphasis [NUMERICAL]
# 	13 : GrayLevelNonUniformity [NUMERICAL]
# 	12 : GrayLevelNonUniformityNormalized [NUMERICAL]
# 	7 : ShortRunLowGrayLevelEmphasis [NUMERICAL]
# 	7 : GrayLevelVariance [NUMERICAL]
# 	3 : RunLengthNonUniformity [NUMERICAL]
# 	3 : RunEntropy [NUMERICAL]
# 	3 : LongRunEmphasis [NUMERICAL]
# 	2 : RunVariance [NUMERICAL]
# 	1 : RunPercentage [NUMERICAL]
# 	1 : RunLengthNonUniformityNormalized [NUMERICAL]
# 	1 : LongRunLowGrayLevelEmphasis [NUMERICAL]
#
# Attribute in nodes with depth <= 2:
# 	130 : LongRunHighGrayLevelEmphasis [NUMERICAL]
# 	55 : LowGrayLevelRunEmphasis [NUMERICAL]
# 	33 : ShortRunHighGrayLevelEmphasis [NUMERICAL]
# 	33 : HighGrayLevelRunEmphasis [NUMERICAL]
# 	27 : RunEntropy [NUMERICAL]
# 	25 : GrayLevelVariance [NUMERICAL]
# 	25 : GrayLevelNonUniformity [NUMERICAL]
# 	24 : ShortRunLowGrayLevelEmphasis [NUMERICAL]
# 	23 : GrayLevelNonUniformityNormalized [NUMERICAL]
# 	12 : LongRunLowGrayLevelEmphasis [NUMERICAL]
# 	11 : RunVariance [NUMERICAL]
# 	10 : ShortRunEmphasis [NUMERICAL]
# 	10 : RunLengthNonUniformityNormalized [NUMERICAL]
# 	6 : RunLengthNonUniformity [NUMERICAL]
# 	6 : LongRunEmphasis [NUMERICAL]
# 	3 : RunPercentage [NUMERICAL]
#
# Attribute in nodes with depth <= 3:
# 	169 : LongRunHighGrayLevelEmphasis [NUMERICAL]
# 	86 : LowGrayLevelRunEmphasis [NUMERICAL]
# 	85 : RunEntropy [NUMERICAL]
# 	58 : GrayLevelNonUniformityNormalized [NUMERICAL]
# 	51 : ShortRunHighGrayLevelEmphasis [NUMERICAL]
# 	43 : HighGrayLevelRunEmphasis [NUMERICAL]
# 	40 : GrayLevelVariance [NUMERICAL]
# 	35 : LongRunLowGrayLevelEmphasis [NUMERICAL]
# 	34 : GrayLevelNonUniformity [NUMERICAL]
# 	31 : ShortRunLowGrayLevelEmphasis [NUMERICAL]
# 	24 : ShortRunEmphasis [NUMERICAL]
# 	24 : RunLengthNonUniformityNormalized [NUMERICAL]
# 	16 : RunVariance [NUMERICAL]
# 	11 : RunLengthNonUniformity [NUMERICAL]
# 	10 : LongRunEmphasis [NUMERICAL]
# 	8 : RunPercentage [NUMERICAL]
#
# Attribute in nodes with depth <= 5:
# 	231 : LongRunHighGrayLevelEmphasis [NUMERICAL]
# 	144 : RunEntropy [NUMERICAL]
# 	101 : LowGrayLevelRunEmphasis [NUMERICAL]
# 	87 : GrayLevelNonUniformityNormalized [NUMERICAL]
# 	85 : GrayLevelVariance [NUMERICAL]
# 	69 : ShortRunHighGrayLevelEmphasis [NUMERICAL]
# 	67 : GrayLevelNonUniformity [NUMERICAL]
# 	60 : ShortRunLowGrayLevelEmphasis [NUMERICAL]
# 	57 : HighGrayLevelRunEmphasis [NUMERICAL]
# 	55 : LongRunLowGrayLevelEmphasis [NUMERICAL]
# 	40 : ShortRunEmphasis [NUMERICAL]
# 	38 : RunLengthNonUniformityNormalized [NUMERICAL]
# 	24 : RunVariance [NUMERICAL]
# 	18 : RunLengthNonUniformity [NUMERICAL]
# 	16 : RunPercentage [NUMERICAL]
# 	15 : LongRunEmphasis [NUMERICAL]
#
# Condition type in nodes:
# 	1107 : HigherCondition
# Condition type in nodes with depth <= 0:
# 	72 : HigherCondition
# Condition type in nodes with depth <= 1:
# 	216 : HigherCondition
# Condition type in nodes with depth <= 2:
# 	433 : HigherCondition
# Condition type in nodes with depth <= 3:
# 	725 : HigherCondition
# Condition type in nodes with depth <= 5:
# 	1107 : HigherCondition
#
# Training logs:
# Number of iteration to final model: 72
# 	Iter:1 train-loss:1.213462 valid-loss:1.245485  train-accuracy:0.957576 valid-accuracy:0.929643
# 	Iter:2 train-loss:1.070595 valid-loss:1.098687  train-accuracy:0.984445 valid-accuracy:1.000000
# 	Iter:3 train-loss:0.952438 valid-loss:0.973219  train-accuracy:0.984445 valid-accuracy:0.964822
# 	Iter:4 train-loss:0.850935 valid-loss:0.871932  train-accuracy:0.987273 valid-accuracy:0.982411
# 	Iter:5 train-loss:0.764098 valid-loss:0.777886  train-accuracy:0.984445 valid-accuracy:0.982411
# 	Iter:6 train-loss:0.685729 valid-loss:0.692942  train-accuracy:0.987273 valid-accuracy:1.000000
# 	Iter:16 train-loss:0.265967 valid-loss:0.288639  train-accuracy:0.995758 valid-accuracy:1.000000
# 	Iter:26 train-loss:0.117903 valid-loss:0.157520  train-accuracy:0.998586 valid-accuracy:0.982411
# 	Iter:36 train-loss:0.058542 valid-loss:0.093310  train-accuracy:0.998586 valid-accuracy:0.982411
# 	Iter:46 train-loss:0.032363 valid-loss:0.075574  train-accuracy:0.998586 valid-accuracy:0.982411
# 	Iter:56 train-loss:0.019009 valid-loss:0.060944  train-accuracy:1.000000 valid-accuracy:0.982411
# 	Iter:66 train-loss:0.012877 valid-loss:0.052476  train-accuracy:1.000000 valid-accuracy:0.982411
# 	Iter:76 train-loss:0.008391 valid-loss:0.048631  train-accuracy:1.000000 valid-accuracy:0.982411
# 	Iter:86 train-loss:0.005344 valid-loss:0.051760  train-accuracy:1.000000 valid-accuracy:0.982411
# 	Iter:96 train-loss:0.003289 valid-loss:0.061849  train-accuracy:1.000000 valid-accuracy:0.982411

# %%
# Model features
model.make_inspector().features()
# Out:
# ["GrayLevelNonUniformity" (1; #0),
#  "GrayLevelNonUniformityNormalized" (1; #1),
#  "GrayLevelVariance" (1; #2),
#  "HighGrayLevelRunEmphasis" (1; #3),
#  "LongRunEmphasis" (1; #4),
#  "LongRunHighGrayLevelEmphasis" (1; #5),
#  "LongRunLowGrayLevelEmphasis" (1; #6),
#  "LowGrayLevelRunEmphasis" (1; #7),
#  "RunEntropy" (1; #8),
#  "RunLengthNonUniformity" (1; #9),
#  "RunLengthNonUniformityNormalized" (1; #10),
#  "RunPercentage" (1; #11),
#  "RunVariance" (1; #12),
#  "ShortRunEmphasis" (1; #13),
#  "ShortRunHighGrayLevelEmphasis" (1; #14),
#  "ShortRunLowGrayLevelEmphasis" (1; #15)]

# %%
# Feature importance
model.make_inspector().variable_importances()
# Out:
# {'INV_MEAN_MIN_DEPTH': [("LongRunHighGrayLevelEmphasis" (1; #5),
#    0.591436788655758),
#   ("LowGrayLevelRunEmphasis" (1; #7), 0.22827567752932407),
#   ("HighGrayLevelRunEmphasis" (1; #3), 0.2241786099245764),
#   ("ShortRunHighGrayLevelEmphasis" (1; #14), 0.21585189645175462),
#   ("RunEntropy" (1; #8), 0.21331135110648347),
#   ("GrayLevelNonUniformityNormalized" (1; #1), 0.20789476473726648),
#   ("ShortRunLowGrayLevelEmphasis" (1; #15), 0.20559179277553996),
#   ("GrayLevelNonUniformity" (1; #0), 0.20441390056091657),
#   ("GrayLevelVariance" (1; #2), 0.20099846618605088),
#   ("LongRunLowGrayLevelEmphasis" (1; #6), 0.19480122941527103),
#   ("RunLengthNonUniformityNormalized" (1; #10), 0.1947499025169051),
#   ("ShortRunEmphasis" (1; #13), 0.1933637466273442),
#   ("RunVariance" (1; #12), 0.19142981099305),
#   ("LongRunEmphasis" (1; #4), 0.1907815039687179),
#   ("RunLengthNonUniformity" (1; #9), 0.19022689045038935),
#   ("RunPercentage" (1; #11), 0.18837780118770206)],
#  'SUM_SCORE': [("LongRunHighGrayLevelEmphasis" (1; #5), 427.03046551308773),
#   ("GrayLevelNonUniformity" (1; #0), 23.722522484575695),
#   ("RunEntropy" (1; #8), 22.971382347095037),
#   ("GrayLevelNonUniformityNormalized" (1; #1), 16.25499507978782),
#   ("ShortRunHighGrayLevelEmphasis" (1; #14), 7.9304032806747395),
#   ("RunVariance" (1; #12), 7.570695422400361),
#   ("ShortRunEmphasis" (1; #13), 7.383797915080283),
#   ("RunLengthNonUniformityNormalized" (1; #10), 7.2825839626851305),
#   ("HighGrayLevelRunEmphasis" (1; #3), 6.251668377933713),
#   ("LowGrayLevelRunEmphasis" (1; #7), 5.716478565969375),
#   ("ShortRunLowGrayLevelEmphasis" (1; #15), 5.478107685057458),
#   ("LongRunLowGrayLevelEmphasis" (1; #6), 4.2541179935600475),
#   ("LongRunEmphasis" (1; #4), 4.046548015036616),
#   ("RunPercentage" (1; #11), 2.2295786555294854),
#   ("GrayLevelVariance" (1; #2), 2.1562432468561044),
#   ("RunLengthNonUniformity" (1; #9), 1.8180716916450839)],
#  'NUM_AS_ROOT': [("LongRunHighGrayLevelEmphasis" (1; #5), 58.0),
#   ("LowGrayLevelRunEmphasis" (1; #7), 7.0),
#   ("HighGrayLevelRunEmphasis" (1; #3), 5.0),
#   ("ShortRunLowGrayLevelEmphasis" (1; #15), 2.0)],
#  'NUM_NODES': [("LongRunHighGrayLevelEmphasis" (1; #5), 231.0),
#   ("RunEntropy" (1; #8), 144.0),
#   ("LowGrayLevelRunEmphasis" (1; #7), 101.0),
#   ("GrayLevelNonUniformityNormalized" (1; #1), 87.0),
#   ("GrayLevelVariance" (1; #2), 85.0),
#   ("ShortRunHighGrayLevelEmphasis" (1; #14), 69.0),
#   ("GrayLevelNonUniformity" (1; #0), 67.0),
#   ("ShortRunLowGrayLevelEmphasis" (1; #15), 60.0),
#   ("HighGrayLevelRunEmphasis" (1; #3), 57.0),
#   ("LongRunLowGrayLevelEmphasis" (1; #6), 55.0),
#   ("ShortRunEmphasis" (1; #13), 40.0),
#   ("RunLengthNonUniformityNormalized" (1; #10), 38.0),
#   ("RunVariance" (1; #12), 24.0),
#   ("RunLengthNonUniformity" (1; #9), 18.0),
#   ("RunPercentage" (1; #11), 16.0),
#   ("LongRunEmphasis" (1; #4), 15.0)]}

# %%
# Model self evaluation
model.make_inspector().evaluation()
# Out:
# Evaluation(num_examples=None, accuracy=0.9824107885360718, loss=0.04657125473022461, rmse=None, ndcg=None, aucs=None, auuc=None, qini=None)

# %%
logs = model.make_inspector().training_logs()

plt.figure(figsize=(12, 4))
plt.subplot(1, 2, 1)
plt.plot([log.num_trees for log in logs], [log.evaluation.accuracy for log in logs])
plt.xlabel("Number of trees")
plt.ylabel("Accuracy (out-of-bag)")
plt.subplot(1, 2, 2)
plt.plot([log.num_trees for log in logs], [log.evaluation.loss for log in logs])
plt.xlabel("Number of trees")
plt.ylabel("Logloss (out-of-bag)")
plt.show()

# %% [markdown]
# Calculate the score of our hold-out validation dataset

# %%
predictions = model.predict(val_ds)
y_true      = validation_data["label"]

from sklearn.metrics import roc_auc_score
ROC_AUC = roc_auc_score(y_true, predictions)
print("The ROC AUC score is %.5f" % ROC_AUC )
# Out:
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 56ms/step
# The ROC AUC score is 0.97222

# %%
# Compute binary classification metrics with sklearn
import numpy as np
from sklearn.metrics import (
    accuracy_score,
    precision_score,
    recall_score,
    f1_score,
    roc_auc_score,
    average_precision_score,
    confusion_matrix,
    classification_report,
    matthews_corrcoef,
    log_loss,
    brier_score_loss,
)

# Get predictions (probabilities or class labels)
preds = model.predict(test_ds)
# If model outputs probabilities, convert to labels by threshold 0.5
if preds.ndim == 2:
    # For TFDF classification, preds may be class probabilities with shape (N, 2)
    if preds.shape[1] == 2:
        pos_probs = preds[:, 1]
    else:
        # If single-probability column (positive class)
        pos_probs = preds[:, -1]
    y_pred = (pos_probs >= 0.5).astype(int)
else:
    # Already class labels
    y_pred = preds.astype(int)
    pos_probs = None

# Ground truth labels (must be 0/1 integers)
y_true = test_data["label"].astype(int).to_numpy()

# Core metrics
metrics = {}
metrics["accuracy"] = accuracy_score(y_true, y_pred)
metrics["precision"] = precision_score(y_true, y_pred, zero_division=0)
metrics["recall"] = recall_score(y_true, y_pred, zero_division=0)
metrics["f1"] = f1_score(y_true, y_pred, zero_division=0)
metrics["mcc"] = matthews_corrcoef(y_true, y_pred)

# Probabilistic metrics (only if we have probabilities)
if pos_probs is not None:
    metrics["roc_auc"] = roc_auc_score(y_true, pos_probs)
    metrics["pr_auc"] = average_precision_score(y_true, pos_probs)
    metrics["log_loss"] = log_loss(y_true, pos_probs, labels=[0,1])
    metrics["brier_score"] = brier_score_loss(y_true, pos_probs)

# Confusion matrix and detailed report
cm = confusion_matrix(y_true, y_pred, labels=[0,1])
report = classification_report(y_true, y_pred, digits=4)

print("Sklearn binary metrics:")
for k, v in metrics.items():
    print(f"{k}: {v:.4f}")
print("\nConfusion matrix:\n", cm)
print("\nClassification report:\n", report)
# Out:
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 62ms/step
# Sklearn binary metrics:
# accuracy: 0.9690
# precision: 0.8333
# recall: 0.8333
# f1: 0.8333
# mcc: 0.8162
# roc_auc: 0.9957
# pr_auc: 0.9614
# log_loss: 0.0851
# brier_score: 0.0212
#
# Confusion matrix:
#  [[115   2]
#  [  2  10]]
#
# Classification report:
#                precision    recall  f1-score   support
#
#            0     0.9829    0.9829    0.9829       117
#            1     0.8333    0.8333    0.8333        12
#
#     accuracy                         0.9690       129
#    macro avg     0.9081    0.9081    0.9081       129
# weighted avg     0.9690    0.9690    0.9690       129
