# %%
# Import packages and modules
import numpy  as np
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow_decision_forests as tfdf

from sklearn.model_selection import train_test_split
# Out:
# 2026-08-12 05:56:50.386829: I tensorflow/core/util/port.cc:113] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2026-08-12 05:56:50.731968: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2026-08-12 05:56:55.250003: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
# Check the version of TensorFlow Decision Forests
print("Found TensorFlow Decision Forests v" + tfdf.__version__)
# Out:
# Found TensorFlow Decision Forests v1.9.1

# %%
datasetPath = 'dataset/firstorder/kernel5-radius5/dataset.csv'

# %%
# Parameters
datasetPath = "dataset/firstorder/kernel6/1.dataset.csv"

# %%
# train/validation/test = 70/10/20
dataset = pd.read_csv(datasetPath)

train_data, temp_data = train_test_split(dataset, test_size=0.3, random_state=42)
validation_data, test_data = train_test_split(temp_data, test_size=2/3, random_state=42)

# %%
from sklearn.utils.class_weight import compute_class_weight

# tinh class weight tren tap train
classes = np.array([0, 1])
weights = compute_class_weight(class_weight="balanced", classes=classes, y=train_data["label"])
class_weight = {0: weights[0], 1: weights[1]}

# gan sample_weight cho tung dong
train_data["sample_weight"] = train_data["label"].map(class_weight)
validation_data["sample_weight"] = validation_data["label"].map(class_weight)
test_data["sample_weight"] = test_data["label"].map(class_weight)

# Convert the dataset into a TensorFlow dataset.
train_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    train_data, label="label", weight="sample_weight"
)         
val_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    validation_data, label="label", weight="sample_weight"
)
test_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    test_data, label="label", weight="sample_weight"
)
# Out:
# 2026-08-12 05:57:07.615222: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:984] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2026-08-12 05:57:07.616749: W tensorflow/core/common_runtime/gpu/gpu_device.cc:2251] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...

# %%
import keras

# %%
# %%time

# Train a Random Forest model.
model = tfdf.keras.RandomForestModel()

# Add evaluation metrics
model.compile(
    metrics=["accuracy"]
)
model.fit(x=train_ds)

# # Train a Gradient Boosted Trees model.
# model = tfdf.keras.GradientBoostedTreesModel(num_trees=1500)
# model.fit(train_ds)
# Out:
# Use /tmp/tmpalwivswa as temporary training directory
# Reading training dataset...
# Training dataset read in 0:00:02.475930. Found 450 examples.
# Training model...
# Model trained in 0:00:00.053627
# Compiling model...
# [INFO 26-08-12 05:57:10.3012 UTC kernel.cc:1233] Loading model from path /tmp/tmpalwivswa/model/ with prefix 72bca92e674f4512
# [INFO 26-08-12 05:57:10.3106 UTC decision_forest.cc:734] Model loaded with 300 root(s), 8232 node(s), and 18 input feature(s).
# [INFO 26-08-12 05:57:10.3107 UTC abstract_model.cc:1362] Engine "RandomForestOptPred" built
# [INFO 26-08-12 05:57:10.3107 UTC kernel.cc:1061] Use fast generic engine
# Model compiled.
# CPU times: user 5.68 s, sys: 5.66 ms, total: 5.69 s
# Wall time: 5.59 s

# %%
# Evaluate the model
evaluate = model.evaluate(val_ds, return_dict=True)
print()

for name, value in evaluate.items():
    print(f"{name}: {value:.4f}")
# Out:
# WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 1/1 [==============================] - ETA: 0s - loss: 0.0000e+00 - accuracy: 1.0000
# 1/1 [==============================] - 6s 6s/step - loss: 0.0000e+00 - accuracy: 1.0000
# loss: 0.0000
# accuracy: 1.0000

# %%
# Model Summary
model.summary()
# Out:
# Model: "random_forest_model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
# =================================================================
# Total params: 1 (1.00 Byte)
# Trainable params: 0 (0.00 Byte)
# Non-trainable params: 1 (1.00 Byte)
# _________________________________________________________________
# Type: "RANDOM_FOREST"
# Task: CLASSIFICATION
# Label: "__LABEL"
#
# Input Features (18):
# 	10Percentile
# 	90Percentile
# 	Energy
# 	Entropy
# 	InterquartileRange
# 	Kurtosis
# 	Maximum
# 	Mean
# 	MeanAbsoluteDeviation
# 	Median
# 	Minimum
# 	Range
# 	RobustMeanAbsoluteDeviation
# 	RootMeanSquared
# 	Skewness
# 	TotalEnergy
# 	Uniformity
# 	Variance
#
# Trained with weights
#
# Variable Importance: INV_MEAN_MIN_DEPTH:
#     1.                      "Energy"  0.237257 ################
#     2.                 "TotalEnergy"  0.233862 ##############
#     3.                        "Mean"  0.230923 #############
#     4.             "RootMeanSquared"  0.230069 #############
#     5.                      "Median"  0.229796 #############
#     6.                "10Percentile"  0.219229 ##########
#     7.                "90Percentile"  0.211733 #######
#     8.                     "Maximum"  0.209308 ######
#     9.                    "Skewness"  0.205180 #####
#    10.                    "Kurtosis"  0.205089 #####
#    11.                     "Minimum"  0.199251 ###
#    12.                     "Entropy"  0.195601 ##
#    13.          "InterquartileRange"  0.193278 #
#    14.                       "Range"  0.192606 #
#    15.                  "Uniformity"  0.192087 #
#    16.                    "Variance"  0.188976
#    17.       "MeanAbsoluteDeviation"  0.188737
#    18. "RobustMeanAbsoluteDeviation"  0.187906
#
# Variable Importance: NUM_AS_ROOT:
#     1.     "TotalEnergy" 50.000000 ################
#     2.          "Energy" 49.000000 ###############
#     3. "RootMeanSquared" 49.000000 ###############
#     4.          "Median" 47.000000 ###############
#     5.            "Mean" 36.000000 ###########
#     6.    "90Percentile" 28.000000 ########
#     7.         "Maximum" 22.000000 ######
#     8.    "10Percentile" 17.000000 #####
#     9.         "Minimum"  1.000000
#    10.      "Uniformity"  1.000000
#
# Variable Importance: NUM_NODES:
#     1.                    "Skewness" 302.000000 ################
#     2.                      "Energy" 289.000000 ##############
#     3.                        "Mean" 283.000000 ##############
#     4.                    "Kurtosis" 272.000000 #############
#     5.                      "Median" 271.000000 #############
#     6.                "10Percentile" 260.000000 ############
#     7.             "RootMeanSquared" 248.000000 ###########
#     8.                 "TotalEnergy" 244.000000 ##########
#     9.                     "Maximum" 224.000000 ########
#    10.                "90Percentile" 221.000000 ########
#    11.                     "Minimum" 206.000000 #######
#    12.                     "Entropy" 205.000000 #######
#    13.                       "Range" 193.000000 #####
#    14.                  "Uniformity" 178.000000 ####
#    15.          "InterquartileRange" 171.000000 ###
#    16.                    "Variance" 137.000000
#    17.       "MeanAbsoluteDeviation" 134.000000
#    18. "RobustMeanAbsoluteDeviation" 128.000000
#
# Variable Importance: SUM_SCORE:
#     1.                      "Energy" 11208.701857 ################
#     2.                 "TotalEnergy" 10871.036213 ###############
#     3.             "RootMeanSquared" 10701.073934 ###############
#     4.                      "Median" 10123.273924 ##############
#     5.                        "Mean" 8840.782306 ############
#     6.                "90Percentile" 6398.651215 ########
#     7.                "10Percentile" 5582.488853 #######
#     8.                     "Maximum" 5385.321610 #######
#     9.                    "Kurtosis" 3152.184047 ###
#    10.                    "Skewness" 2707.064687 ##
#    11.                     "Minimum" 2275.682312 ##
#    12.                     "Entropy" 2255.163145 ##
#    13.                       "Range" 1553.761551 #
#    14.          "InterquartileRange" 1512.082580 #
#    15.                  "Uniformity" 1310.973176
#    16.                    "Variance" 982.941622
#    17. "RobustMeanAbsoluteDeviation" 909.759300
#    18.       "MeanAbsoluteDeviation" 846.620364
#
#
#
# Winner takes all: true
# Out-of-bag evaluation: accuracy:0.850389 logloss:0.557724
# Number of trees: 300
# Total number of nodes: 8232
#
# Number of nodes by tree:
# Count: 300 Average: 27.44 StdDev: 3.6941
# Min: 15 Max: 39 Ignored: 0
# ----------------------------------------------
# [ 15, 16)  1   0.33%   0.33%
# [ 16, 17)  0   0.00%   0.33%
# [ 17, 18)  0   0.00%   0.33%
# [ 18, 20)  4   1.33%   1.67% #
# [ 20, 21)  0   0.00%   1.67%
# [ 21, 22) 18   6.00%   7.67% ###
# [ 22, 23)  0   0.00%   7.67%
# [ 23, 25) 30  10.00%  17.67% ####
# [ 25, 26) 48  16.00%  33.67% #######
# [ 26, 27)  0   0.00%  33.67%
# [ 27, 28) 67  22.33%  56.00% ##########
# [ 28, 30) 58  19.33%  75.33% #########
# [ 30, 31)  0   0.00%  75.33%
# [ 31, 32) 43  14.33%  89.67% ######
# [ 32, 33)  0   0.00%  89.67%
# [ 33, 35) 21   7.00%  96.67% ###
# [ 35, 36)  8   2.67%  99.33% #
# [ 36, 37)  0   0.00%  99.33%
# [ 37, 38)  1   0.33%  99.67%
# [ 38, 39]  1   0.33% 100.00%
#
# Depth by leafs:
# Count: 4266 Average: 4.57079 StdDev: 1.60177
# Min: 1 Max: 10 Ignored: 0
# ----------------------------------------------
# [  1,  2)    4   0.09%   0.09%
# [  2,  3)  369   8.65%   8.74% ####
# [  3,  4)  792  18.57%  27.31% ########
# [  4,  5) 1048  24.57%  51.88% ##########
# [  5,  6)  898  21.05%  72.93% #########
# [  6,  7)  644  15.10%  88.02% ######
# [  7,  8)  321   7.52%  95.55% ###
# [  8,  9)  130   3.05%  98.59% #
# [  9, 10)   52   1.22%  99.81%
# [ 10, 10]    8   0.19% 100.00%
#
# Number of training obs by leaf:
# Count: 4266 Average: 31.6456 StdDev: 62.1829
# Min: 5 Max: 348 Ignored: 0
# ----------------------------------------------
# [   5,  22) 3222  75.53%  75.53% ##########
# [  22,  39)  339   7.95%  83.47% #
# [  39,  56)  210   4.92%  88.40% #
# [  56,  73)   43   1.01%  89.40%
# [  73,  91)   50   1.17%  90.58%
# [  91, 108)   48   1.13%  91.70%
# [ 108, 125)   47   1.10%  92.80%
# [ 125, 142)    8   0.19%  92.99%
# [ 142, 159)    0   0.00%  92.99%
# [ 159, 177)    2   0.05%  93.04%
# [ 177, 194)   14   0.33%  93.37%
# [ 194, 211)   55   1.29%  94.66%
# [ 211, 228)   65   1.52%  96.18%
# [ 228, 245)   43   1.01%  97.19%
# [ 245, 263)   33   0.77%  97.96%
# [ 263, 280)   26   0.61%  98.57%
# [ 280, 297)   23   0.54%  99.11%
# [ 297, 314)   17   0.40%  99.51%
# [ 314, 331)   12   0.28%  99.79%
# [ 331, 348]    9   0.21% 100.00%
#
# Attribute in nodes:
# 	302 : Skewness [NUMERICAL]
# 	289 : Energy [NUMERICAL]
# 	283 : Mean [NUMERICAL]
# 	272 : Kurtosis [NUMERICAL]
# 	271 : Median [NUMERICAL]
# 	260 : 10Percentile [NUMERICAL]
# 	248 : RootMeanSquared [NUMERICAL]
# 	244 : TotalEnergy [NUMERICAL]
# 	224 : Maximum [NUMERICAL]
# 	221 : 90Percentile [NUMERICAL]
# 	206 : Minimum [NUMERICAL]
# 	205 : Entropy [NUMERICAL]
# 	193 : Range [NUMERICAL]
# 	178 : Uniformity [NUMERICAL]
# 	171 : InterquartileRange [NUMERICAL]
# 	137 : Variance [NUMERICAL]
# 	134 : MeanAbsoluteDeviation [NUMERICAL]
# 	128 : RobustMeanAbsoluteDeviation [NUMERICAL]
#
# Attribute in nodes with depth <= 0:
# 	50 : TotalEnergy [NUMERICAL]
# 	49 : RootMeanSquared [NUMERICAL]
# 	49 : Energy [NUMERICAL]
# 	47 : Median [NUMERICAL]
# 	36 : Mean [NUMERICAL]
# 	28 : 90Percentile [NUMERICAL]
# 	22 : Maximum [NUMERICAL]
# 	17 : 10Percentile [NUMERICAL]
# 	1 : Uniformity [NUMERICAL]
# 	1 : Minimum [NUMERICAL]
#
# Attribute in nodes with depth <= 1:
# 	126 : Energy [NUMERICAL]
# 	109 : Mean [NUMERICAL]
# 	107 : TotalEnergy [NUMERICAL]
# 	106 : Median [NUMERICAL]
# 	105 : RootMeanSquared [NUMERICAL]
# 	93 : 10Percentile [NUMERICAL]
# 	62 : Maximum [NUMERICAL]
# 	58 : 90Percentile [NUMERICAL]
# 	42 : Minimum [NUMERICAL]
# 	31 : Entropy [NUMERICAL]
# 	13 : Uniformity [NUMERICAL]
# 	12 : Range [NUMERICAL]
# 	11 : Kurtosis [NUMERICAL]
# 	9 : Skewness [NUMERICAL]
# 	6 : InterquartileRange [NUMERICAL]
# 	3 : Variance [NUMERICAL]
# 	2 : RobustMeanAbsoluteDeviation [NUMERICAL]
# 	1 : MeanAbsoluteDeviation [NUMERICAL]
#
# Attribute in nodes with depth <= 2:
# 	177 : Energy [NUMERICAL]
# 	169 : Mean [NUMERICAL]
# 	162 : Median [NUMERICAL]
# 	157 : TotalEnergy [NUMERICAL]
# 	156 : 10Percentile [NUMERICAL]
# 	143 : RootMeanSquared [NUMERICAL]
# 	89 : 90Percentile [NUMERICAL]
# 	88 : Skewness [NUMERICAL]
# 	86 : Maximum [NUMERICAL]
# 	83 : Kurtosis [NUMERICAL]
# 	75 : Entropy [NUMERICAL]
# 	74 : Minimum [NUMERICAL]
# 	63 : InterquartileRange [NUMERICAL]
# 	53 : Range [NUMERICAL]
# 	48 : Uniformity [NUMERICAL]
# 	35 : RobustMeanAbsoluteDeviation [NUMERICAL]
# 	33 : Variance [NUMERICAL]
# 	28 : MeanAbsoluteDeviation [NUMERICAL]
#
# Attribute in nodes with depth <= 3:
# 	218 : Energy [NUMERICAL]
# 	202 : Mean [NUMERICAL]
# 	197 : 10Percentile [NUMERICAL]
# 	194 : Median [NUMERICAL]
# 	192 : TotalEnergy [NUMERICAL]
# 	189 : Skewness [NUMERICAL]
# 	179 : RootMeanSquared [NUMERICAL]
# 	175 : Kurtosis [NUMERICAL]
# 	140 : Maximum [NUMERICAL]
# 	137 : Minimum [NUMERICAL]
# 	134 : 90Percentile [NUMERICAL]
# 	119 : Entropy [NUMERICAL]
# 	105 : InterquartileRange [NUMERICAL]
# 	102 : Range [NUMERICAL]
# 	93 : Uniformity [NUMERICAL]
# 	73 : Variance [NUMERICAL]
# 	69 : MeanAbsoluteDeviation [NUMERICAL]
# 	55 : RobustMeanAbsoluteDeviation [NUMERICAL]
#
# Attribute in nodes with depth <= 5:
# 	282 : Skewness [NUMERICAL]
# 	278 : Energy [NUMERICAL]
# 	266 : Mean [NUMERICAL]
# 	252 : Kurtosis [NUMERICAL]
# 	251 : Median [NUMERICAL]
# 	247 : 10Percentile [NUMERICAL]
# 	227 : TotalEnergy [NUMERICAL]
# 	227 : RootMeanSquared [NUMERICAL]
# 	209 : Maximum [NUMERICAL]
# 	203 : 90Percentile [NUMERICAL]
# 	193 : Minimum [NUMERICAL]
# 	185 : Entropy [NUMERICAL]
# 	171 : Range [NUMERICAL]
# 	160 : Uniformity [NUMERICAL]
# 	157 : InterquartileRange [NUMERICAL]
# 	122 : Variance [NUMERICAL]
# 	122 : MeanAbsoluteDeviation [NUMERICAL]
# 	103 : RobustMeanAbsoluteDeviation [NUMERICAL]
#
# Condition type in nodes:
# 	3966 : HigherCondition
# Condition type in nodes with depth <= 0:
# 	300 : HigherCondition
# Condition type in nodes with depth <= 1:
# 	896 : HigherCondition
# Condition type in nodes with depth <= 2:
# 	1719 : HigherCondition
# Condition type in nodes with depth <= 3:
# 	2573 : HigherCondition
# Condition type in nodes with depth <= 5:
# 	3655 : HigherCondition
# Node format: NOT_SET
#
# Training OOB:
# 	trees: 1, Out-of-bag evaluation: accuracy:0.795805 logloss:7.35993
# 	trees: 12, Out-of-bag evaluation: accuracy:0.811109 logloss:4.37298
# 	trees: 22, Out-of-bag evaluation: accuracy:0.837354 logloss:1.71221
# 	trees: 32, Out-of-bag evaluation: accuracy:0.837354 logloss:1.43997
# 	trees: 42, Out-of-bag evaluation: accuracy:0.834764 logloss:0.911525
# 	trees: 53, Out-of-bag evaluation: accuracy:0.836059 logloss:0.920967
# 	trees: 63, Out-of-bag evaluation: accuracy:0.842576 logloss:0.658518
# 	trees: 73, Out-of-bag evaluation: accuracy:0.837354 logloss:0.645302
# 	trees: 83, Out-of-bag evaluation: accuracy:0.845167 logloss:0.645282
# 	trees: 94, Out-of-bag evaluation: accuracy:0.834764 logloss:0.606108
# 	trees: 105, Out-of-bag evaluation: accuracy:0.836059 logloss:0.604752
# 	trees: 115, Out-of-bag evaluation: accuracy:0.836059 logloss:0.596282
# 	trees: 126, Out-of-bag evaluation: accuracy:0.841281 logloss:0.597659
# 	trees: 136, Out-of-bag evaluation: accuracy:0.841281 logloss:0.600615
# 	trees: 146, Out-of-bag evaluation: accuracy:0.839985 logloss:0.59957
# 	trees: 156, Out-of-bag evaluation: accuracy:0.850389 logloss:0.561722
# 	trees: 167, Out-of-bag evaluation: accuracy:0.847798 logloss:0.566093
# 	trees: 177, Out-of-bag evaluation: accuracy:0.842576 logloss:0.569401
# 	trees: 187, Out-of-bag evaluation: accuracy:0.842576 logloss:0.571024
# 	trees: 197, Out-of-bag evaluation: accuracy:0.841281 logloss:0.572591
# 	trees: 207, Out-of-bag evaluation: accuracy:0.842576 logloss:0.570581
# 	trees: 217, Out-of-bag evaluation: accuracy:0.843871 logloss:0.570993
# 	trees: 227, Out-of-bag evaluation: accuracy:0.843871 logloss:0.569248
# 	trees: 237, Out-of-bag evaluation: accuracy:0.843871 logloss:0.569498
# 	trees: 247, Out-of-bag evaluation: accuracy:0.836059 logloss:0.57212
# 	trees: 257, Out-of-bag evaluation: accuracy:0.841281 logloss:0.564631
# 	trees: 267, Out-of-bag evaluation: accuracy:0.847798 logloss:0.562259
# 	trees: 278, Out-of-bag evaluation: accuracy:0.849093 logloss:0.56271
# 	trees: 288, Out-of-bag evaluation: accuracy:0.849093 logloss:0.56013
# 	trees: 298, Out-of-bag evaluation: accuracy:0.849093 logloss:0.557689
# 	trees: 300, Out-of-bag evaluation: accuracy:0.850389 logloss:0.557724

# %%
# Model features
model.make_inspector().features()
# Out:
# ["10Percentile" (1; #0),
#  "90Percentile" (1; #1),
#  "Energy" (1; #2),
#  "Entropy" (1; #3),
#  "InterquartileRange" (1; #4),
#  "Kurtosis" (1; #5),
#  "Maximum" (1; #6),
#  "Mean" (1; #7),
#  "MeanAbsoluteDeviation" (1; #8),
#  "Median" (1; #9),
#  "Minimum" (1; #10),
#  "Range" (1; #11),
#  "RobustMeanAbsoluteDeviation" (1; #12),
#  "RootMeanSquared" (1; #13),
#  "Skewness" (1; #14),
#  "TotalEnergy" (1; #15),
#  "Uniformity" (1; #16),
#  "Variance" (1; #17)]

# %%
# Feature importance
model.make_inspector().variable_importances()
# Out:
# {'INV_MEAN_MIN_DEPTH': [("Energy" (1; #2), 0.23725705698433966),
#   ("TotalEnergy" (1; #15), 0.23386178720734221),
#   ("Mean" (1; #7), 0.23092330061394958),
#   ("RootMeanSquared" (1; #13), 0.23006944427790085),
#   ("Median" (1; #9), 0.22979556350399996),
#   ("10Percentile" (1; #0), 0.21922897631927837),
#   ("90Percentile" (1; #1), 0.21173271755545398),
#   ("Maximum" (1; #6), 0.20930776806905396),
#   ("Skewness" (1; #14), 0.2051798032755153),
#   ("Kurtosis" (1; #5), 0.2050892899582082),
#   ("Minimum" (1; #10), 0.19925116017489303),
#   ("Entropy" (1; #3), 0.19560098535739617),
#   ("InterquartileRange" (1; #4), 0.19327824613402947),
#   ("Range" (1; #11), 0.1926058355713357),
#   ("Uniformity" (1; #16), 0.19208744479583295),
#   ("Variance" (1; #17), 0.1889763624760088),
#   ("MeanAbsoluteDeviation" (1; #8), 0.1887369991509132),
#   ("RobustMeanAbsoluteDeviation" (1; #12), 0.1879063709842148)],
#  'SUM_SCORE': [("Energy" (1; #2), 11208.701856520633),
#   ("TotalEnergy" (1; #15), 10871.036212700918),
#   ("RootMeanSquared" (1; #13), 10701.073934247517),
#   ("Median" (1; #9), 10123.273924465177),
#   ("Mean" (1; #7), 8840.782306209723),
#   ("90Percentile" (1; #1), 6398.651215456386),
#   ("10Percentile" (1; #0), 5582.488853241865),
#   ("Maximum" (1; #6), 5385.321610231444),
#   ("Kurtosis" (1; #5), 3152.1840471546657),
#   ("Skewness" (1; #14), 2707.0646871967774),
#   ("Minimum" (1; #10), 2275.6823120567647),
#   ("Entropy" (1; #3), 2255.163144509782),
#   ("Range" (1; #11), 1553.761551233844),
#   ("InterquartileRange" (1; #4), 1512.0825803280654),
#   ("Uniformity" (1; #16), 1310.9731762620672),
#   ("Variance" (1; #17), 982.9416217643954),
#   ("RobustMeanAbsoluteDeviation" (1; #12), 909.7593000808808),
#   ("MeanAbsoluteDeviation" (1; #8), 846.6203642040524)],
#  'NUM_AS_ROOT': [("TotalEnergy" (1; #15), 50.0),
#   ("Energy" (1; #2), 49.0),
#   ("RootMeanSquared" (1; #13), 49.0),
#   ("Median" (1; #9), 47.0),
#   ("Mean" (1; #7), 36.0),
#   ("90Percentile" (1; #1), 28.0),
#   ("Maximum" (1; #6), 22.0),
#   ("10Percentile" (1; #0), 17.0),
#   ("Minimum" (1; #10), 1.0),
#   ("Uniformity" (1; #16), 1.0)],
#  'NUM_NODES': [("Skewness" (1; #14), 302.0),
#   ("Energy" (1; #2), 289.0),
#   ("Mean" (1; #7), 283.0),
#   ("Kurtosis" (1; #5), 272.0),
#   ("Median" (1; #9), 271.0),
#   ("10Percentile" (1; #0), 260.0),
#   ("RootMeanSquared" (1; #13), 248.0),
#   ("TotalEnergy" (1; #15), 244.0),
#   ("Maximum" (1; #6), 224.0),
#   ("90Percentile" (1; #1), 221.0),
#   ("Minimum" (1; #10), 206.0),
#   ("Entropy" (1; #3), 205.0),
#   ("Range" (1; #11), 193.0),
#   ("Uniformity" (1; #16), 178.0),
#   ("InterquartileRange" (1; #4), 171.0),
#   ("Variance" (1; #17), 137.0),
#   ("MeanAbsoluteDeviation" (1; #8), 134.0),
#   ("RobustMeanAbsoluteDeviation" (1; #12), 128.0)]}

# %%
# Model self evaluation
model.make_inspector().evaluation()
# Out:
# Evaluation(num_examples=450, accuracy=0.850388599573605, loss=0.5577244243219185, rmse=None, ndcg=None, aucs=None, auuc=None, qini=None)

# %%
logs = model.make_inspector().training_logs()

plt.figure(figsize=(12, 4))
plt.subplot(1, 2, 1)
plt.plot([log.num_trees for log in logs], [log.evaluation.accuracy for log in logs])
plt.xlabel("Number of trees")
plt.ylabel("Accuracy (out-of-bag)")
plt.subplot(1, 2, 2)
plt.plot([log.num_trees for log in logs], [log.evaluation.loss for log in logs])
plt.xlabel("Number of trees")
plt.ylabel("Logloss (out-of-bag)")
plt.show()

# %% [markdown]
# Calculate the score of our hold-out validation dataset

# %%
predictions = model.predict(val_ds)
y_true      = validation_data["label"]

from sklearn.metrics import roc_auc_score
ROC_AUC = roc_auc_score(y_true, predictions)
print("The ROC AUC score is %.5f" % ROC_AUC )
# Out:
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 60ms/step
# The ROC AUC score is 1.00000

# %%
# Compute binary classification metrics with sklearn
import numpy as np
from sklearn.metrics import (
    accuracy_score,
    precision_score,
    recall_score,
    f1_score,
    roc_auc_score,
    average_precision_score,
    confusion_matrix,
    classification_report,
    matthews_corrcoef,
    log_loss,
    brier_score_loss,
)

# Get predictions (probabilities or class labels)
preds = model.predict(test_ds)
# If model outputs probabilities, convert to labels by threshold 0.5
if preds.ndim == 2:
    # For TFDF classification, preds may be class probabilities with shape (N, 2)
    if preds.shape[1] == 2:
        pos_probs = preds[:, 1]
    else:
        # If single-probability column (positive class)
        pos_probs = preds[:, -1]
    y_pred = (pos_probs >= 0.5).astype(int)
else:
    # Already class labels
    y_pred = preds.astype(int)
    pos_probs = None

# Ground truth labels (must be 0/1 integers)
y_true = test_data["label"].astype(int).to_numpy()

# Core metrics
metrics = {}
metrics["accuracy"] = accuracy_score(y_true, y_pred)
metrics["precision"] = precision_score(y_true, y_pred, zero_division=0)
metrics["recall"] = recall_score(y_true, y_pred, zero_division=0)
metrics["f1"] = f1_score(y_true, y_pred, zero_division=0)
metrics["mcc"] = matthews_corrcoef(y_true, y_pred)

# Probabilistic metrics (only if we have probabilities)
if pos_probs is not None:
    metrics["roc_auc"] = roc_auc_score(y_true, pos_probs)
    metrics["pr_auc"] = average_precision_score(y_true, pos_probs)
    metrics["log_loss"] = log_loss(y_true, pos_probs, labels=[0,1])
    metrics["brier_score"] = brier_score_loss(y_true, pos_probs)

# Confusion matrix and detailed report
cm = confusion_matrix(y_true, y_pred, labels=[0,1])
report = classification_report(y_true, y_pred, digits=4)

print("Sklearn binary metrics:")
for k, v in metrics.items():
    print(f"{k}: {v:.4f}")
print("\nConfusion matrix:\n", cm)
print("\nClassification report:\n", report)
# Out:
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 61ms/step
# Sklearn binary metrics:
# accuracy: 0.8837
# precision: 0.5556
# recall: 0.5882
# f1: 0.5714
# mcc: 0.5045
# roc_auc: 0.9244
# pr_auc: 0.7575
# log_loss: 0.2122
# brier_score: 0.0689
#
# Confusion matrix:
#  [[104   8]
#  [  7  10]]
#
# Classification report:
#                precision    recall  f1-score   support
#
#            0     0.9369    0.9286    0.9327       112
#            1     0.5556    0.5882    0.5714        17
#
#     accuracy                         0.8837       129
#    macro avg     0.7462    0.7584    0.7521       129
# weighted avg     0.8867    0.8837    0.8851       129
