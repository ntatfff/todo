# %%
# Import packages and modules
import numpy  as np
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow_decision_forests as tfdf

from sklearn.model_selection import train_test_split
# Out:
# 2026-08-12 05:41:40.485269: I tensorflow/core/util/port.cc:113] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2026-08-12 05:41:40.827182: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2026-08-12 05:41:45.214276: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
# Check the version of TensorFlow Decision Forests
print("Found TensorFlow Decision Forests v" + tfdf.__version__)
# Out:
# Found TensorFlow Decision Forests v1.9.1

# %%
datasetPath = 'dataset/firstorder/kernel5-radius5/dataset.csv'

# %%
# Parameters
datasetPath = "dataset/glszm/kernel6/1.dataset.csv"

# %%
# train/validation/test = 70/10/20
dataset = pd.read_csv(datasetPath)

train_data, temp_data = train_test_split(dataset, test_size=0.3, random_state=42)
validation_data, test_data = train_test_split(temp_data, test_size=2/3, random_state=42)

# %%
from sklearn.utils.class_weight import compute_class_weight

# tinh class weight tren tap train
classes = np.array([0, 1])
weights = compute_class_weight(class_weight="balanced", classes=classes, y=train_data["label"])
class_weight = {0: weights[0], 1: weights[1]}

# gan sample_weight cho tung dong
train_data["sample_weight"] = train_data["label"].map(class_weight)
validation_data["sample_weight"] = validation_data["label"].map(class_weight)
test_data["sample_weight"] = test_data["label"].map(class_weight)

# Convert the dataset into a TensorFlow dataset.
train_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    train_data, label="label", weight="sample_weight"
)         
val_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    validation_data, label="label", weight="sample_weight"
)
test_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    test_data, label="label", weight="sample_weight"
)
# Out:
# 2026-08-12 05:42:00.260399: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:984] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2026-08-12 05:42:00.262013: W tensorflow/core/common_runtime/gpu/gpu_device.cc:2251] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...

# %%
import keras

# %%
# %%time

# Train a Gradient Boosted Trees model.
model = tfdf.keras.GradientBoostedTreesModel()

# Add evaluation metrics
model.compile(
    metrics=["accuracy"]
)
model.fit(x=train_ds)

# # Train a Gradient Boosted Trees model.
# model = tfdf.keras.GradientBoostedTreesModel(num_trees=1500)
# model.fit(train_ds)
# Out:
# Use /tmp/tmpc8jo4m9a as temporary training directory
# Reading training dataset...
# [WARNING 26-08-12 05:42:00.4009 UTC gradient_boosted_trees.cc:1840] "goss_alpha" set but "sampling_method" not equal to "GOSS".
# [WARNING 26-08-12 05:42:00.4012 UTC gradient_boosted_trees.cc:1851] "goss_beta" set but "sampling_method" not equal to "GOSS".
# [WARNING 26-08-12 05:42:00.4012 UTC gradient_boosted_trees.cc:1865] "selective_gradient_boosting_ratio" set but "sampling_method" not equal to "SELGB".
# Training dataset read in 0:00:02.385769. Found 450 examples.
# Training model...
# Model trained in 0:00:00.518573
# Compiling model...
# [INFO 26-08-12 05:42:03.3288 UTC kernel.cc:1233] Loading model from path /tmp/tmpc8jo4m9a/model/ with prefix 72dabaca9dfc4b16
# [INFO 26-08-12 05:42:03.3334 UTC quick_scorer_extended.cc:911] The binary was compiled without AVX2 support, but your CPU supports it. Enable it for faster model inference.
# [INFO 26-08-12 05:42:03.3338 UTC abstract_model.cc:1362] Engine "GradientBoostedTreesQuickScorerExtended" built
# [INFO 26-08-12 05:42:03.3338 UTC kernel.cc:1061] Use fast generic engine
# Model compiled.
# CPU times: user 5.75 s, sys: 771 ms, total: 6.52 s
# Wall time: 5.88 s

# %%
# Evaluate the model
evaluate = model.evaluate(val_ds, return_dict=True)
print()

for name, value in evaluate.items():
    print(f"{name}: {value:.4f}")
# Out:
# WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 1/1 [==============================] - ETA: 0s - loss: 0.0000e+00 - accuracy: 0.9844
# 1/1 [==============================] - 3s 3s/step - loss: 0.0000e+00 - accuracy: 0.9844
# loss: 0.0000
# accuracy: 0.9844

# %%
# Model Summary
model.summary()
# Out:
# Model: "gradient_boosted_trees_model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
# =================================================================
# Total params: 1 (1.00 Byte)
# Trainable params: 0 (0.00 Byte)
# Non-trainable params: 1 (1.00 Byte)
# _________________________________________________________________
# Type: "GRADIENT_BOOSTED_TREES"
# Task: CLASSIFICATION
# Label: "__LABEL"
#
# Input Features (16):
# 	GrayLevelNonUniformity
# 	GrayLevelNonUniformityNormalized
# 	GrayLevelVariance
# 	HighGrayLevelZoneEmphasis
# 	LargeAreaEmphasis
# 	LargeAreaHighGrayLevelEmphasis
# 	LargeAreaLowGrayLevelEmphasis
# 	LowGrayLevelZoneEmphasis
# 	SizeZoneNonUniformity
# 	SizeZoneNonUniformityNormalized
# 	SmallAreaEmphasis
# 	SmallAreaHighGrayLevelEmphasis
# 	SmallAreaLowGrayLevelEmphasis
# 	ZoneEntropy
# 	ZonePercentage
# 	ZoneVariance
#
# Trained with weights
#
# Variable Importance: INV_MEAN_MIN_DEPTH:
#     1.   "LargeAreaHighGrayLevelEmphasis"  0.295110 ################
#     2.        "HighGrayLevelZoneEmphasis"  0.261427 ##########
#     3.                      "ZoneEntropy"  0.229360 #####
#     4.           "GrayLevelNonUniformity"  0.226742 #####
#     5. "GrayLevelNonUniformityNormalized"  0.224151 #####
#     6.   "SmallAreaHighGrayLevelEmphasis"  0.222611 ####
#     7.    "LargeAreaLowGrayLevelEmphasis"  0.214989 ###
#     8.    "SmallAreaLowGrayLevelEmphasis"  0.214758 ###
#     9.         "LowGrayLevelZoneEmphasis"  0.214530 ###
#    10.                "GrayLevelVariance"  0.214324 ###
#    11.  "SizeZoneNonUniformityNormalized"  0.199178 #
#    12.                "SmallAreaEmphasis"  0.195094
#    13.            "SizeZoneNonUniformity"  0.194789
#    14.                   "ZonePercentage"  0.194378
#    15.                "LargeAreaEmphasis"  0.190650
#    16.                     "ZoneVariance"  0.190438
#
# Variable Importance: NUM_AS_ROOT:
#     1.        "HighGrayLevelZoneEmphasis" 32.000000 ################
#     2.   "LargeAreaHighGrayLevelEmphasis" 32.000000 ################
#     3.   "SmallAreaHighGrayLevelEmphasis" 17.000000 #######
#     4.    "SmallAreaLowGrayLevelEmphasis" 12.000000 ####
#     5.           "GrayLevelNonUniformity"  9.000000 ###
#     6.         "LowGrayLevelZoneEmphasis"  8.000000 ##
#     7.                      "ZoneEntropy"  6.000000 #
#     8.    "LargeAreaLowGrayLevelEmphasis"  5.000000 #
#     9. "GrayLevelNonUniformityNormalized"  4.000000
#    10.                "GrayLevelVariance"  3.000000
#
# Variable Importance: NUM_NODES:
#     1.        "HighGrayLevelZoneEmphasis" 222.000000 ################
#     2.   "LargeAreaHighGrayLevelEmphasis" 214.000000 ###############
#     3.                      "ZoneEntropy" 204.000000 ##############
#     4.           "GrayLevelNonUniformity" 183.000000 ############
#     5.   "SmallAreaHighGrayLevelEmphasis" 151.000000 ##########
#     6. "GrayLevelNonUniformityNormalized" 148.000000 #########
#     7.         "LowGrayLevelZoneEmphasis" 131.000000 ########
#     8.    "LargeAreaLowGrayLevelEmphasis" 129.000000 ########
#     9.    "SmallAreaLowGrayLevelEmphasis" 122.000000 #######
#    10.                "GrayLevelVariance" 114.000000 #######
#    11.            "SizeZoneNonUniformity" 66.000000 ###
#    12.  "SizeZoneNonUniformityNormalized" 60.000000 ##
#    13.                "SmallAreaEmphasis" 55.000000 ##
#    14.                   "ZonePercentage" 34.000000
#    15.                "LargeAreaEmphasis" 32.000000
#    16.                     "ZoneVariance" 29.000000
#
# Variable Importance: SUM_SCORE:
#     1.        "HighGrayLevelZoneEmphasis" 362.539033 ################
#     2.           "GrayLevelNonUniformity" 54.063226 ##
#     3.   "LargeAreaHighGrayLevelEmphasis" 36.864138 #
#     4. "GrayLevelNonUniformityNormalized" 31.448967 #
#     5.   "SmallAreaHighGrayLevelEmphasis" 11.695014
#     6.                "LargeAreaEmphasis" 11.058747
#     7.    "LargeAreaLowGrayLevelEmphasis"  9.108876
#     8.         "LowGrayLevelZoneEmphasis"  8.706536
#     9.                      "ZoneEntropy"  4.843299
#    10.    "SmallAreaLowGrayLevelEmphasis"  3.516571
#    11.  "SizeZoneNonUniformityNormalized"  2.601808
#    12.            "SizeZoneNonUniformity"  2.321629
#    13.                     "ZoneVariance"  2.257101
#    14.                "GrayLevelVariance"  2.131891
#    15.                "SmallAreaEmphasis"  1.658018
#    16.                   "ZonePercentage"  0.737214
#
#
#
# Loss: BINOMIAL_LOG_LIKELIHOOD
# Validation loss value: 0.0266824
# Number of trees per iteration: 1
# Node format: NOT_SET
# Number of trees: 128
# Total number of nodes: 3916
#
# Number of nodes by tree:
# Count: 128 Average: 30.5938 StdDev: 6.82532
# Min: 15 Max: 45 Ignored: 0
# ----------------------------------------------
# [ 15, 16)  1   0.78%   0.78% #
# [ 16, 18)  5   3.91%   4.69% ###
# [ 18, 19)  0   0.00%   4.69%
# [ 19, 21)  4   3.12%   7.81% ##
# [ 21, 22)  6   4.69%  12.50% ###
# [ 22, 24)  8   6.25%  18.75% ####
# [ 24, 25)  0   0.00%  18.75%
# [ 25, 27)  9   7.03%  25.78% #####
# [ 27, 28) 11   8.59%  34.38% ######
# [ 28, 30)  9   7.03%  41.41% #####
# [ 30, 32) 18  14.06%  55.47% ##########
# [ 32, 33)  0   0.00%  55.47%
# [ 33, 35) 18  14.06%  69.53% ##########
# [ 35, 36) 13  10.16%  79.69% #######
# [ 36, 38)  5   3.91%  83.59% ###
# [ 38, 39)  0   0.00%  83.59%
# [ 39, 41) 10   7.81%  91.41% ######
# [ 41, 42)  6   4.69%  96.09% ###
# [ 42, 44)  3   2.34%  98.44% ##
# [ 44, 45]  2   1.56% 100.00% #
#
# Depth by leafs:
# Count: 2022 Average: 4.34224 StdDev: 0.909662
# Min: 1 Max: 5 Ignored: 0
# ----------------------------------------------
# [ 1, 2)    7   0.35%   0.35%
# [ 2, 3)  100   4.95%   5.29% #
# [ 3, 4)  267  13.20%  18.50% ##
# [ 4, 5)  468  23.15%  41.64% ####
# [ 5, 5] 1180  58.36% 100.00% ##########
#
# Number of training obs by leaf:
# Count: 2022 Average: 25.7646 StdDev: 52.618
# Min: 5 Max: 331 Ignored: 0
# ----------------------------------------------
# [   5,  21) 1597  78.98%  78.98% ##########
# [  21,  37)  155   7.67%  86.65% #
# [  37,  54)   48   2.37%  89.02%
# [  54,  70)   45   2.23%  91.25%
# [  70,  86)   25   1.24%  92.48%
# [  86, 103)   11   0.54%  93.03%
# [ 103, 119)   10   0.49%  93.52%
# [ 119, 135)    5   0.25%  93.77%
# [ 135, 152)    8   0.40%  94.16%
# [ 152, 168)    9   0.45%  94.61%
# [ 168, 184)   18   0.89%  95.50%
# [ 184, 201)   17   0.84%  96.34%
# [ 201, 217)   17   0.84%  97.18%
# [ 217, 233)   22   1.09%  98.27%
# [ 233, 250)   13   0.64%  98.91%
# [ 250, 266)    7   0.35%  99.26%
# [ 266, 282)    0   0.00%  99.26%
# [ 282, 299)    6   0.30%  99.55%
# [ 299, 315)    6   0.30%  99.85%
# [ 315, 331]    3   0.15% 100.00%
#
# Attribute in nodes:
# 	222 : HighGrayLevelZoneEmphasis [NUMERICAL]
# 	214 : LargeAreaHighGrayLevelEmphasis [NUMERICAL]
# 	204 : ZoneEntropy [NUMERICAL]
# 	183 : GrayLevelNonUniformity [NUMERICAL]
# 	151 : SmallAreaHighGrayLevelEmphasis [NUMERICAL]
# 	148 : GrayLevelNonUniformityNormalized [NUMERICAL]
# 	131 : LowGrayLevelZoneEmphasis [NUMERICAL]
# 	129 : LargeAreaLowGrayLevelEmphasis [NUMERICAL]
# 	122 : SmallAreaLowGrayLevelEmphasis [NUMERICAL]
# 	114 : GrayLevelVariance [NUMERICAL]
# 	66 : SizeZoneNonUniformity [NUMERICAL]
# 	60 : SizeZoneNonUniformityNormalized [NUMERICAL]
# 	55 : SmallAreaEmphasis [NUMERICAL]
# 	34 : ZonePercentage [NUMERICAL]
# 	32 : LargeAreaEmphasis [NUMERICAL]
# 	29 : ZoneVariance [NUMERICAL]
#
# Attribute in nodes with depth <= 0:
# 	32 : LargeAreaHighGrayLevelEmphasis [NUMERICAL]
# 	32 : HighGrayLevelZoneEmphasis [NUMERICAL]
# 	17 : SmallAreaHighGrayLevelEmphasis [NUMERICAL]
# 	12 : SmallAreaLowGrayLevelEmphasis [NUMERICAL]
# 	9 : GrayLevelNonUniformity [NUMERICAL]
# 	8 : LowGrayLevelZoneEmphasis [NUMERICAL]
# 	6 : ZoneEntropy [NUMERICAL]
# 	5 : LargeAreaLowGrayLevelEmphasis [NUMERICAL]
# 	4 : GrayLevelNonUniformityNormalized [NUMERICAL]
# 	3 : GrayLevelVariance [NUMERICAL]
#
# Attribute in nodes with depth <= 1:
# 	61 : LargeAreaHighGrayLevelEmphasis [NUMERICAL]
# 	53 : HighGrayLevelZoneEmphasis [NUMERICAL]
# 	41 : GrayLevelNonUniformityNormalized [NUMERICAL]
# 	38 : ZoneEntropy [NUMERICAL]
# 	32 : SmallAreaHighGrayLevelEmphasis [NUMERICAL]
# 	32 : GrayLevelNonUniformity [NUMERICAL]
# 	30 : GrayLevelVariance [NUMERICAL]
# 	26 : LargeAreaLowGrayLevelEmphasis [NUMERICAL]
# 	23 : LowGrayLevelZoneEmphasis [NUMERICAL]
# 	17 : SmallAreaLowGrayLevelEmphasis [NUMERICAL]
# 	8 : SizeZoneNonUniformityNormalized [NUMERICAL]
# 	7 : ZonePercentage [NUMERICAL]
# 	5 : SmallAreaEmphasis [NUMERICAL]
# 	4 : SizeZoneNonUniformity [NUMERICAL]
#
# Attribute in nodes with depth <= 2:
# 	124 : LargeAreaHighGrayLevelEmphasis [NUMERICAL]
# 	111 : HighGrayLevelZoneEmphasis [NUMERICAL]
# 	88 : GrayLevelNonUniformity [NUMERICAL]
# 	78 : ZoneEntropy [NUMERICAL]
# 	64 : GrayLevelNonUniformityNormalized [NUMERICAL]
# 	52 : SmallAreaLowGrayLevelEmphasis [NUMERICAL]
# 	51 : SmallAreaHighGrayLevelEmphasis [NUMERICAL]
# 	45 : LowGrayLevelZoneEmphasis [NUMERICAL]
# 	44 : LargeAreaLowGrayLevelEmphasis [NUMERICAL]
# 	44 : GrayLevelVariance [NUMERICAL]
# 	21 : SizeZoneNonUniformityNormalized [NUMERICAL]
# 	16 : ZonePercentage [NUMERICAL]
# 	16 : SmallAreaEmphasis [NUMERICAL]
# 	11 : SizeZoneNonUniformity [NUMERICAL]
# 	5 : ZoneVariance [NUMERICAL]
# 	5 : LargeAreaEmphasis [NUMERICAL]
#
# Attribute in nodes with depth <= 3:
# 	172 : HighGrayLevelZoneEmphasis [NUMERICAL]
# 	161 : LargeAreaHighGrayLevelEmphasis [NUMERICAL]
# 	143 : ZoneEntropy [NUMERICAL]
# 	133 : GrayLevelNonUniformity [NUMERICAL]
# 	100 : GrayLevelNonUniformityNormalized [NUMERICAL]
# 	90 : SmallAreaHighGrayLevelEmphasis [NUMERICAL]
# 	88 : LargeAreaLowGrayLevelEmphasis [NUMERICAL]
# 	84 : LowGrayLevelZoneEmphasis [NUMERICAL]
# 	83 : SmallAreaLowGrayLevelEmphasis [NUMERICAL]
# 	77 : GrayLevelVariance [NUMERICAL]
# 	44 : SizeZoneNonUniformityNormalized [NUMERICAL]
# 	33 : SizeZoneNonUniformity [NUMERICAL]
# 	32 : SmallAreaEmphasis [NUMERICAL]
# 	30 : ZonePercentage [NUMERICAL]
# 	19 : LargeAreaEmphasis [NUMERICAL]
# 	15 : ZoneVariance [NUMERICAL]
#
# Attribute in nodes with depth <= 5:
# 	222 : HighGrayLevelZoneEmphasis [NUMERICAL]
# 	214 : LargeAreaHighGrayLevelEmphasis [NUMERICAL]
# 	204 : ZoneEntropy [NUMERICAL]
# 	183 : GrayLevelNonUniformity [NUMERICAL]
# 	151 : SmallAreaHighGrayLevelEmphasis [NUMERICAL]
# 	148 : GrayLevelNonUniformityNormalized [NUMERICAL]
# 	131 : LowGrayLevelZoneEmphasis [NUMERICAL]
# 	129 : LargeAreaLowGrayLevelEmphasis [NUMERICAL]
# 	122 : SmallAreaLowGrayLevelEmphasis [NUMERICAL]
# 	114 : GrayLevelVariance [NUMERICAL]
# 	66 : SizeZoneNonUniformity [NUMERICAL]
# 	60 : SizeZoneNonUniformityNormalized [NUMERICAL]
# 	55 : SmallAreaEmphasis [NUMERICAL]
# 	34 : ZonePercentage [NUMERICAL]
# 	32 : LargeAreaEmphasis [NUMERICAL]
# 	29 : ZoneVariance [NUMERICAL]
#
# Condition type in nodes:
# 	1894 : HigherCondition
# Condition type in nodes with depth <= 0:
# 	128 : HigherCondition
# Condition type in nodes with depth <= 1:
# 	377 : HigherCondition
# Condition type in nodes with depth <= 2:
# 	775 : HigherCondition
# Condition type in nodes with depth <= 3:
# 	1304 : HigherCondition
# Condition type in nodes with depth <= 5:
# 	1894 : HigherCondition
#
# Training logs:
# Number of iteration to final model: 128
# 	Iter:1 train-loss:1.208906 valid-loss:1.220371  train-accuracy:0.981373 valid-accuracy:0.954606
# 	Iter:2 train-loss:1.064970 valid-loss:1.083896  train-accuracy:0.987104 valid-accuracy:0.954606
# 	Iter:3 train-loss:0.941515 valid-loss:0.964034  train-accuracy:0.987104 valid-accuracy:0.954606
# 	Iter:4 train-loss:0.838732 valid-loss:0.883213  train-accuracy:0.985672 valid-accuracy:0.954606
# 	Iter:5 train-loss:0.750017 valid-loss:0.786470  train-accuracy:0.985672 valid-accuracy:0.954606
# 	Iter:6 train-loss:0.673864 valid-loss:0.702554  train-accuracy:0.985672 valid-accuracy:0.954606
# 	Iter:16 train-loss:0.263121 valid-loss:0.290466  train-accuracy:0.992836 valid-accuracy:0.984869
# 	Iter:26 train-loss:0.119325 valid-loss:0.144316  train-accuracy:0.998567 valid-accuracy:1.000000
# 	Iter:36 train-loss:0.059994 valid-loss:0.093469  train-accuracy:0.998567 valid-accuracy:1.000000
# 	Iter:46 train-loss:0.029866 valid-loss:0.089452  train-accuracy:1.000000 valid-accuracy:1.000000
# 	Iter:56 train-loss:0.016180 valid-loss:0.061582  train-accuracy:1.000000 valid-accuracy:1.000000
# 	Iter:66 train-loss:0.009019 valid-loss:0.052909  train-accuracy:1.000000 valid-accuracy:1.000000
# 	Iter:76 train-loss:0.005095 valid-loss:0.059997  train-accuracy:1.000000 valid-accuracy:1.000000
# 	Iter:86 train-loss:0.002904 valid-loss:0.052351  train-accuracy:1.000000 valid-accuracy:1.000000
# 	Iter:96 train-loss:0.001816 valid-loss:0.043692  train-accuracy:1.000000 valid-accuracy:1.000000
# 	Iter:106 train-loss:0.001092 valid-loss:0.040811  train-accuracy:1.000000 valid-accuracy:1.000000
# 	Iter:116 train-loss:0.000668 valid-loss:0.032184  train-accuracy:1.000000 valid-accuracy:1.000000
# 	Iter:126 train-loss:0.000412 valid-loss:0.029881  train-accuracy:1.000000 valid-accuracy:1.000000
# 	Iter:136 train-loss:0.000245 valid-loss:0.033382  train-accuracy:1.000000 valid-accuracy:1.000000
# 	Iter:146 train-loss:0.000149 valid-loss:0.037610  train-accuracy:1.000000 valid-accuracy:1.000000
# 	Iter:156 train-loss:0.000098 valid-loss:0.041326  train-accuracy:1.000000 valid-accuracy:1.000000

# %%
# Model features
model.make_inspector().features()
# Out:
# ["GrayLevelNonUniformity" (1; #0),
#  "GrayLevelNonUniformityNormalized" (1; #1),
#  "GrayLevelVariance" (1; #2),
#  "HighGrayLevelZoneEmphasis" (1; #3),
#  "LargeAreaEmphasis" (1; #4),
#  "LargeAreaHighGrayLevelEmphasis" (1; #5),
#  "LargeAreaLowGrayLevelEmphasis" (1; #6),
#  "LowGrayLevelZoneEmphasis" (1; #7),
#  "SizeZoneNonUniformity" (1; #8),
#  "SizeZoneNonUniformityNormalized" (1; #9),
#  "SmallAreaEmphasis" (1; #10),
#  "SmallAreaHighGrayLevelEmphasis" (1; #11),
#  "SmallAreaLowGrayLevelEmphasis" (1; #12),
#  "ZoneEntropy" (1; #13),
#  "ZonePercentage" (1; #14),
#  "ZoneVariance" (1; #15)]

# %%
# Feature importance
model.make_inspector().variable_importances()
# Out:
# {'INV_MEAN_MIN_DEPTH': [("LargeAreaHighGrayLevelEmphasis" (1; #5),
#    0.29510967693568907),
#   ("HighGrayLevelZoneEmphasis" (1; #3), 0.26142745989232496),
#   ("ZoneEntropy" (1; #13), 0.2293604706458162),
#   ("GrayLevelNonUniformity" (1; #0), 0.22674160781121852),
#   ("GrayLevelNonUniformityNormalized" (1; #1), 0.22415135794034913),
#   ("SmallAreaHighGrayLevelEmphasis" (1; #11), 0.22261143138622),
#   ("LargeAreaLowGrayLevelEmphasis" (1; #6), 0.21498870835956252),
#   ("SmallAreaLowGrayLevelEmphasis" (1; #12), 0.21475761959118328),
#   ("LowGrayLevelZoneEmphasis" (1; #7), 0.2145296970462431),
#   ("GrayLevelVariance" (1; #2), 0.21432394839487115),
#   ("SizeZoneNonUniformityNormalized" (1; #9), 0.19917844136435914),
#   ("SmallAreaEmphasis" (1; #10), 0.1950938689270278),
#   ("SizeZoneNonUniformity" (1; #8), 0.19478852550153172),
#   ("ZonePercentage" (1; #14), 0.19437845134054313),
#   ("LargeAreaEmphasis" (1; #4), 0.19065047880047367),
#   ("ZoneVariance" (1; #15), 0.19043765537993038)],
#  'SUM_SCORE': [("HighGrayLevelZoneEmphasis" (1; #3), 362.53903333934875),
#   ("GrayLevelNonUniformity" (1; #0), 54.063226029241214),
#   ("LargeAreaHighGrayLevelEmphasis" (1; #5), 36.864137618646375),
#   ("GrayLevelNonUniformityNormalized" (1; #1), 31.44896665447684),
#   ("SmallAreaHighGrayLevelEmphasis" (1; #11), 11.69501350374994),
#   ("LargeAreaEmphasis" (1; #4), 11.058747385380519),
#   ("LargeAreaLowGrayLevelEmphasis" (1; #6), 9.108876165411656),
#   ("LowGrayLevelZoneEmphasis" (1; #7), 8.706535622571547),
#   ("ZoneEntropy" (1; #13), 4.8432993221954534),
#   ("SmallAreaLowGrayLevelEmphasis" (1; #12), 3.516570842407789),
#   ("SizeZoneNonUniformityNormalized" (1; #9), 2.6018084292023986),
#   ("SizeZoneNonUniformity" (1; #8), 2.3216291280718564),
#   ("ZoneVariance" (1; #15), 2.2571007811354784),
#   ("GrayLevelVariance" (1; #2), 2.1318905071307697),
#   ("SmallAreaEmphasis" (1; #10), 1.6580175559578991),
#   ("ZonePercentage" (1; #14), 0.7372137754790964)],
#  'NUM_AS_ROOT': [("HighGrayLevelZoneEmphasis" (1; #3), 32.0),
#   ("LargeAreaHighGrayLevelEmphasis" (1; #5), 32.0),
#   ("SmallAreaHighGrayLevelEmphasis" (1; #11), 17.0),
#   ("SmallAreaLowGrayLevelEmphasis" (1; #12), 12.0),
#   ("GrayLevelNonUniformity" (1; #0), 9.0),
#   ("LowGrayLevelZoneEmphasis" (1; #7), 8.0),
#   ("ZoneEntropy" (1; #13), 6.0),
#   ("LargeAreaLowGrayLevelEmphasis" (1; #6), 5.0),
#   ("GrayLevelNonUniformityNormalized" (1; #1), 4.0),
#   ("GrayLevelVariance" (1; #2), 3.0)],
#  'NUM_NODES': [("HighGrayLevelZoneEmphasis" (1; #3), 222.0),
#   ("LargeAreaHighGrayLevelEmphasis" (1; #5), 214.0),
#   ("ZoneEntropy" (1; #13), 204.0),
#   ("GrayLevelNonUniformity" (1; #0), 183.0),
#   ("SmallAreaHighGrayLevelEmphasis" (1; #11), 151.0),
#   ("GrayLevelNonUniformityNormalized" (1; #1), 148.0),
#   ("LowGrayLevelZoneEmphasis" (1; #7), 131.0),
#   ("LargeAreaLowGrayLevelEmphasis" (1; #6), 129.0),
#   ("SmallAreaLowGrayLevelEmphasis" (1; #12), 122.0),
#   ("GrayLevelVariance" (1; #2), 114.0),
#   ("SizeZoneNonUniformity" (1; #8), 66.0),
#   ("SizeZoneNonUniformityNormalized" (1; #9), 60.0),
#   ("SmallAreaEmphasis" (1; #10), 55.0),
#   ("ZonePercentage" (1; #14), 34.0),
#   ("LargeAreaEmphasis" (1; #4), 32.0),
#   ("ZoneVariance" (1; #15), 29.0)]}

# %%
# Model self evaluation
model.make_inspector().evaluation()
# Out:
# Evaluation(num_examples=None, accuracy=1.0, loss=0.02668236382305622, rmse=None, ndcg=None, aucs=None, auuc=None, qini=None)

# %%
logs = model.make_inspector().training_logs()

plt.figure(figsize=(12, 4))
plt.subplot(1, 2, 1)
plt.plot([log.num_trees for log in logs], [log.evaluation.accuracy for log in logs])
plt.xlabel("Number of trees")
plt.ylabel("Accuracy (out-of-bag)")
plt.subplot(1, 2, 2)
plt.plot([log.num_trees for log in logs], [log.evaluation.loss for log in logs])
plt.xlabel("Number of trees")
plt.ylabel("Logloss (out-of-bag)")
plt.show()

# %% [markdown]
# Calculate the score of our hold-out validation dataset

# %%
predictions = model.predict(val_ds)
y_true      = validation_data["label"]

from sklearn.metrics import roc_auc_score
ROC_AUC = roc_auc_score(y_true, predictions)
print("The ROC AUC score is %.5f" % ROC_AUC )
# Out:
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 58ms/step
# The ROC AUC score is 0.99138

# %%
# Compute binary classification metrics with sklearn
import numpy as np
from sklearn.metrics import (
    accuracy_score,
    precision_score,
    recall_score,
    f1_score,
    roc_auc_score,
    average_precision_score,
    confusion_matrix,
    classification_report,
    matthews_corrcoef,
    log_loss,
    brier_score_loss,
)

# Get predictions (probabilities or class labels)
preds = model.predict(test_ds)
# If model outputs probabilities, convert to labels by threshold 0.5
if preds.ndim == 2:
    # For TFDF classification, preds may be class probabilities with shape (N, 2)
    if preds.shape[1] == 2:
        pos_probs = preds[:, 1]
    else:
        # If single-probability column (positive class)
        pos_probs = preds[:, -1]
    y_pred = (pos_probs >= 0.5).astype(int)
else:
    # Already class labels
    y_pred = preds.astype(int)
    pos_probs = None

# Ground truth labels (must be 0/1 integers)
y_true = test_data["label"].astype(int).to_numpy()

# Core metrics
metrics = {}
metrics["accuracy"] = accuracy_score(y_true, y_pred)
metrics["precision"] = precision_score(y_true, y_pred, zero_division=0)
metrics["recall"] = recall_score(y_true, y_pred, zero_division=0)
metrics["f1"] = f1_score(y_true, y_pred, zero_division=0)
metrics["mcc"] = matthews_corrcoef(y_true, y_pred)

# Probabilistic metrics (only if we have probabilities)
if pos_probs is not None:
    metrics["roc_auc"] = roc_auc_score(y_true, pos_probs)
    metrics["pr_auc"] = average_precision_score(y_true, pos_probs)
    metrics["log_loss"] = log_loss(y_true, pos_probs, labels=[0,1])
    metrics["brier_score"] = brier_score_loss(y_true, pos_probs)

# Confusion matrix and detailed report
cm = confusion_matrix(y_true, y_pred, labels=[0,1])
report = classification_report(y_true, y_pred, digits=4)

print("Sklearn binary metrics:")
for k, v in metrics.items():
    print(f"{k}: {v:.4f}")
print("\nConfusion matrix:\n", cm)
print("\nClassification report:\n", report)
# Out:
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 55ms/step
# Sklearn binary metrics:
# accuracy: 0.9380
# precision: 0.7857
# recall: 0.6875
# f1: 0.7333
# mcc: 0.7004
# roc_auc: 0.9580
# pr_auc: 0.7456
# log_loss: 0.2868
# brier_score: 0.0556
#
# Confusion matrix:
#  [[110   3]
#  [  5  11]]
#
# Classification report:
#                precision    recall  f1-score   support
#
#            0     0.9565    0.9735    0.9649       113
#            1     0.7857    0.6875    0.7333        16
#
#     accuracy                         0.9380       129
#    macro avg     0.8711    0.8305    0.8491       129
# weighted avg     0.9353    0.9380    0.9362       129
