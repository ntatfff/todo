# %%
# Import packages and modules
import numpy  as np
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow_decision_forests as tfdf

from sklearn.model_selection import train_test_split
# Out:
# 2026-08-12 05:58:03.114699: I tensorflow/core/util/port.cc:113] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2026-08-12 05:58:03.458039: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2026-08-12 05:58:08.091700: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
# Check the version of TensorFlow Decision Forests
print("Found TensorFlow Decision Forests v" + tfdf.__version__)
# Out:
# Found TensorFlow Decision Forests v1.9.1

# %%
datasetPath = 'dataset/firstorder/kernel5-radius5/dataset.csv'

# %%
# Parameters
datasetPath = "dataset/gldm/kernel6/1.dataset.csv"

# %%
# train/validation/test = 70/10/20
dataset = pd.read_csv(datasetPath)

train_data, temp_data = train_test_split(dataset, test_size=0.3, random_state=42)
validation_data, test_data = train_test_split(temp_data, test_size=2/3, random_state=42)

# %%
from sklearn.utils.class_weight import compute_class_weight

# tinh class weight tren tap train
classes = np.array([0, 1])
weights = compute_class_weight(class_weight="balanced", classes=classes, y=train_data["label"])
class_weight = {0: weights[0], 1: weights[1]}

# gan sample_weight cho tung dong
train_data["sample_weight"] = train_data["label"].map(class_weight)
validation_data["sample_weight"] = validation_data["label"].map(class_weight)
test_data["sample_weight"] = test_data["label"].map(class_weight)

# Convert the dataset into a TensorFlow dataset.
train_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    train_data, label="label", weight="sample_weight"
)         
val_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    validation_data, label="label", weight="sample_weight"
)
test_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    test_data, label="label", weight="sample_weight"
)
# Out:
# 2026-08-12 05:58:23.345218: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:984] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2026-08-12 05:58:23.347026: W tensorflow/core/common_runtime/gpu/gpu_device.cc:2251] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...

# %%
import keras

# %%
# %%time

# Train a Random Forest model.
model = tfdf.keras.RandomForestModel()

# Add evaluation metrics
model.compile(
    metrics=["accuracy"]
)
model.fit(x=train_ds)

# # Train a Gradient Boosted Trees model.
# model = tfdf.keras.GradientBoostedTreesModel(num_trees=1500)
# model.fit(train_ds)
# Out:
# Use /tmp/tmpjv28qjbf as temporary training directory
# Reading training dataset...
# Training dataset read in 0:00:02.428178. Found 450 examples.
# Training model...
# Model trained in 0:00:00.049056
# Compiling model...
# [INFO 26-08-12 05:58:25.9715 UTC kernel.cc:1233] Loading model from path /tmp/tmpjv28qjbf/model/ with prefix 5406dcc40fa54e25
# [INFO 26-08-12 05:58:25.9797 UTC decision_forest.cc:734] Model loaded with 300 root(s), 7416 node(s), and 14 input feature(s).
# [INFO 26-08-12 05:58:25.9798 UTC abstract_model.cc:1362] Engine "RandomForestOptPred" built
# [INFO 26-08-12 05:58:25.9798 UTC kernel.cc:1061] Use fast generic engine
# Model compiled.
# CPU times: user 5.59 s, sys: 17.1 ms, total: 5.61 s
# Wall time: 5.51 s

# %%
# Evaluate the model
evaluate = model.evaluate(val_ds, return_dict=True)
print()

for name, value in evaluate.items():
    print(f"{name}: {value:.4f}")
# Out:
# WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 1/1 [==============================] - ETA: 0s - loss: 0.0000e+00 - accuracy: 0.9531
# 1/1 [==============================] - 3s 3s/step - loss: 0.0000e+00 - accuracy: 0.9531
# loss: 0.0000
# accuracy: 0.9531

# %%
# Model Summary
model.summary()
# Out:
# Model: "random_forest_model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
# =================================================================
# Total params: 1 (1.00 Byte)
# Trainable params: 0 (0.00 Byte)
# Non-trainable params: 1 (1.00 Byte)
# _________________________________________________________________
# Type: "RANDOM_FOREST"
# Task: CLASSIFICATION
# Label: "__LABEL"
#
# Input Features (14):
# 	DependenceEntropy
# 	DependenceNonUniformity
# 	DependenceNonUniformityNormalized
# 	DependenceVariance
# 	GrayLevelNonUniformity
# 	GrayLevelVariance
# 	HighGrayLevelEmphasis
# 	LargeDependenceEmphasis
# 	LargeDependenceHighGrayLevelEmphasis
# 	LargeDependenceLowGrayLevelEmphasis
# 	LowGrayLevelEmphasis
# 	SmallDependenceEmphasis
# 	SmallDependenceHighGrayLevelEmphasis
# 	SmallDependenceLowGrayLevelEmphasis
#
# Trained with weights
#
# Variable Importance: INV_MEAN_MIN_DEPTH:
#     1.                "HighGrayLevelEmphasis"  0.325733 ################
#     2. "LargeDependenceHighGrayLevelEmphasis"  0.311077 ##############
#     3.                 "LowGrayLevelEmphasis"  0.250947 ######
#     4.                    "DependenceEntropy"  0.244054 #####
#     5.  "SmallDependenceLowGrayLevelEmphasis"  0.227197 ###
#     6. "SmallDependenceHighGrayLevelEmphasis"  0.225052 ###
#     7.  "LargeDependenceLowGrayLevelEmphasis"  0.219687 ##
#     8.               "GrayLevelNonUniformity"  0.216601 ##
#     9.                    "GrayLevelVariance"  0.211131 #
#    10.              "SmallDependenceEmphasis"  0.204036
#    11.              "LargeDependenceEmphasis"  0.203222
#    12.              "DependenceNonUniformity"  0.202898
#    13.    "DependenceNonUniformityNormalized"  0.201085
#    14.                   "DependenceVariance"  0.200754
#
# Variable Importance: NUM_AS_ROOT:
#     1.                "HighGrayLevelEmphasis" 90.000000 ################
#     2. "LargeDependenceHighGrayLevelEmphasis" 77.000000 #############
#     3.                 "LowGrayLevelEmphasis" 54.000000 #########
#     4.  "SmallDependenceLowGrayLevelEmphasis" 31.000000 #####
#     5.  "LargeDependenceLowGrayLevelEmphasis" 23.000000 ###
#     6. "SmallDependenceHighGrayLevelEmphasis" 14.000000 ##
#     7.                    "DependenceEntropy"  6.000000
#     8.               "GrayLevelNonUniformity"  3.000000
#     9.                   "DependenceVariance"  1.000000
#    10.              "LargeDependenceEmphasis"  1.000000
#
# Variable Importance: NUM_NODES:
#     1.                "HighGrayLevelEmphasis" 511.000000 ################
#     2. "LargeDependenceHighGrayLevelEmphasis" 489.000000 ###############
#     3.                    "DependenceEntropy" 396.000000 ###########
#     4.                 "LowGrayLevelEmphasis" 289.000000 ######
#     5. "SmallDependenceHighGrayLevelEmphasis" 271.000000 ######
#     6.               "GrayLevelNonUniformity" 252.000000 #####
#     7.                    "GrayLevelVariance" 247.000000 #####
#     8.  "SmallDependenceLowGrayLevelEmphasis" 209.000000 ###
#     9.  "LargeDependenceLowGrayLevelEmphasis" 202.000000 ###
#    10.              "SmallDependenceEmphasis" 173.000000 ##
#    11.              "DependenceNonUniformity" 150.000000 #
#    12.    "DependenceNonUniformityNormalized" 125.000000
#    13.                   "DependenceVariance" 125.000000
#    14.              "LargeDependenceEmphasis" 119.000000
#
# Variable Importance: SUM_SCORE:
#     1.                "HighGrayLevelEmphasis" 22610.991302 ################
#     2. "LargeDependenceHighGrayLevelEmphasis" 19299.705593 #############
#     3.                 "LowGrayLevelEmphasis" 10904.704783 #######
#     4.                    "DependenceEntropy" 9074.385868 ######
#     5.  "SmallDependenceLowGrayLevelEmphasis" 5004.382308 ##
#     6.  "LargeDependenceLowGrayLevelEmphasis" 3973.583970 ##
#     7. "SmallDependenceHighGrayLevelEmphasis" 3879.657555 ##
#     8.               "GrayLevelNonUniformity" 3590.654227 #
#     9.                    "GrayLevelVariance" 2770.035871 #
#    10.              "SmallDependenceEmphasis" 1600.378229
#    11.              "DependenceNonUniformity" 1314.146768
#    12.    "DependenceNonUniformityNormalized" 1125.122921
#    13.              "LargeDependenceEmphasis" 1066.293329
#    14.                   "DependenceVariance" 947.834786
#
#
#
# Winner takes all: true
# Out-of-bag evaluation: accuracy:0.917495 logloss:0.21427
# Number of trees: 300
# Total number of nodes: 7416
#
# Number of nodes by tree:
# Count: 300 Average: 24.72 StdDev: 3.86112
# Min: 13 Max: 37 Ignored: 0
# ----------------------------------------------
# [ 13, 14)  1   0.33%   0.33%
# [ 14, 15)  0   0.00%   0.33%
# [ 15, 16)  0   0.00%   0.33%
# [ 16, 18)  7   2.33%   2.67% #
# [ 18, 19)  0   0.00%   2.67%
# [ 19, 20) 24   8.00%  10.67% ####
# [ 20, 21)  0   0.00%  10.67%
# [ 21, 23) 41  13.67%  24.33% ######
# [ 23, 24) 58  19.33%  43.67% #########
# [ 24, 25)  0   0.00%  43.67%
# [ 25, 26) 64  21.33%  65.00% ##########
# [ 26, 28) 52  17.33%  82.33% ########
# [ 28, 29)  0   0.00%  82.33%
# [ 29, 30) 24   8.00%  90.33% ####
# [ 30, 31)  0   0.00%  90.33%
# [ 31, 33) 16   5.33%  95.67% ###
# [ 33, 34) 10   3.33%  99.00% ##
# [ 34, 35)  0   0.00%  99.00%
# [ 35, 36)  2   0.67%  99.67%
# [ 36, 37]  1   0.33% 100.00%
#
# Depth by leafs:
# Count: 3858 Average: 4.21903 StdDev: 1.3443
# Min: 1 Max: 10 Ignored: 0
# ----------------------------------------------
# [  1,  2)    6   0.16%   0.16%
# [  2,  3)  302   7.83%   7.98% ###
# [  3,  4)  916  23.74%  31.73% ########
# [  4,  5) 1163  30.15%  61.87% ##########
# [  5,  6)  847  21.95%  83.83% #######
# [  6,  7)  416  10.78%  94.61% ####
# [  7,  8)  142   3.68%  98.29% #
# [  8,  9)   56   1.45%  99.74%
# [  9, 10)    6   0.16%  99.90%
# [ 10, 10]    4   0.10% 100.00%
#
# Number of training obs by leaf:
# Count: 3858 Average: 34.9922 StdDev: 66.3831
# Min: 5 Max: 343 Ignored: 0
# ----------------------------------------------
# [   5,  21) 2707  70.17%  70.17% ##########
# [  21,  38)  445  11.53%  81.70% ##
# [  38,  55)  202   5.24%  86.94% #
# [  55,  72)   64   1.66%  88.60%
# [  72,  89)   54   1.40%  89.99%
# [  89, 106)   39   1.01%  91.01%
# [ 106, 123)   31   0.80%  91.81%
# [ 123, 140)   16   0.41%  92.22%
# [ 140, 157)    9   0.23%  92.46%
# [ 157, 174)   10   0.26%  92.72%
# [ 174, 191)   23   0.60%  93.31%
# [ 191, 208)   34   0.88%  94.19%
# [ 208, 225)   28   0.73%  94.92%
# [ 225, 242)   34   0.88%  95.80%
# [ 242, 259)   36   0.93%  96.73%
# [ 259, 276)   32   0.83%  97.56%
# [ 276, 293)   24   0.62%  98.19%
# [ 293, 310)   34   0.88%  99.07%
# [ 310, 327)   25   0.65%  99.71%
# [ 327, 343]   11   0.29% 100.00%
#
# Attribute in nodes:
# 	511 : HighGrayLevelEmphasis [NUMERICAL]
# 	489 : LargeDependenceHighGrayLevelEmphasis [NUMERICAL]
# 	396 : DependenceEntropy [NUMERICAL]
# 	289 : LowGrayLevelEmphasis [NUMERICAL]
# 	271 : SmallDependenceHighGrayLevelEmphasis [NUMERICAL]
# 	252 : GrayLevelNonUniformity [NUMERICAL]
# 	247 : GrayLevelVariance [NUMERICAL]
# 	209 : SmallDependenceLowGrayLevelEmphasis [NUMERICAL]
# 	202 : LargeDependenceLowGrayLevelEmphasis [NUMERICAL]
# 	173 : SmallDependenceEmphasis [NUMERICAL]
# 	150 : DependenceNonUniformity [NUMERICAL]
# 	125 : DependenceVariance [NUMERICAL]
# 	125 : DependenceNonUniformityNormalized [NUMERICAL]
# 	119 : LargeDependenceEmphasis [NUMERICAL]
#
# Attribute in nodes with depth <= 0:
# 	90 : HighGrayLevelEmphasis [NUMERICAL]
# 	77 : LargeDependenceHighGrayLevelEmphasis [NUMERICAL]
# 	54 : LowGrayLevelEmphasis [NUMERICAL]
# 	31 : SmallDependenceLowGrayLevelEmphasis [NUMERICAL]
# 	23 : LargeDependenceLowGrayLevelEmphasis [NUMERICAL]
# 	14 : SmallDependenceHighGrayLevelEmphasis [NUMERICAL]
# 	6 : DependenceEntropy [NUMERICAL]
# 	3 : GrayLevelNonUniformity [NUMERICAL]
# 	1 : LargeDependenceEmphasis [NUMERICAL]
# 	1 : DependenceVariance [NUMERICAL]
#
# Attribute in nodes with depth <= 1:
# 	218 : HighGrayLevelEmphasis [NUMERICAL]
# 	197 : LargeDependenceHighGrayLevelEmphasis [NUMERICAL]
# 	103 : LowGrayLevelEmphasis [NUMERICAL]
# 	98 : DependenceEntropy [NUMERICAL]
# 	59 : SmallDependenceLowGrayLevelEmphasis [NUMERICAL]
# 	55 : SmallDependenceHighGrayLevelEmphasis [NUMERICAL]
# 	49 : LargeDependenceLowGrayLevelEmphasis [NUMERICAL]
# 	48 : GrayLevelNonUniformity [NUMERICAL]
# 	21 : GrayLevelVariance [NUMERICAL]
# 	11 : LargeDependenceEmphasis [NUMERICAL]
# 	10 : SmallDependenceEmphasis [NUMERICAL]
# 	10 : DependenceVariance [NUMERICAL]
# 	10 : DependenceNonUniformity [NUMERICAL]
# 	5 : DependenceNonUniformityNormalized [NUMERICAL]
#
# Attribute in nodes with depth <= 2:
# 	350 : HighGrayLevelEmphasis [NUMERICAL]
# 	304 : LargeDependenceHighGrayLevelEmphasis [NUMERICAL]
# 	211 : DependenceEntropy [NUMERICAL]
# 	173 : LowGrayLevelEmphasis [NUMERICAL]
# 	117 : SmallDependenceHighGrayLevelEmphasis [NUMERICAL]
# 	112 : GrayLevelNonUniformity [NUMERICAL]
# 	98 : SmallDependenceLowGrayLevelEmphasis [NUMERICAL]
# 	95 : LargeDependenceLowGrayLevelEmphasis [NUMERICAL]
# 	92 : GrayLevelVariance [NUMERICAL]
# 	57 : SmallDependenceEmphasis [NUMERICAL]
# 	44 : LargeDependenceEmphasis [NUMERICAL]
# 	43 : DependenceVariance [NUMERICAL]
# 	43 : DependenceNonUniformityNormalized [NUMERICAL]
# 	41 : DependenceNonUniformity [NUMERICAL]
#
# Attribute in nodes with depth <= 3:
# 	439 : HighGrayLevelEmphasis [NUMERICAL]
# 	393 : LargeDependenceHighGrayLevelEmphasis [NUMERICAL]
# 	299 : DependenceEntropy [NUMERICAL]
# 	214 : LowGrayLevelEmphasis [NUMERICAL]
# 	200 : SmallDependenceHighGrayLevelEmphasis [NUMERICAL]
# 	174 : GrayLevelVariance [NUMERICAL]
# 	173 : GrayLevelNonUniformity [NUMERICAL]
# 	154 : LargeDependenceLowGrayLevelEmphasis [NUMERICAL]
# 	142 : SmallDependenceLowGrayLevelEmphasis [NUMERICAL]
# 	110 : SmallDependenceEmphasis [NUMERICAL]
# 	93 : DependenceNonUniformity [NUMERICAL]
# 	88 : LargeDependenceEmphasis [NUMERICAL]
# 	83 : DependenceNonUniformityNormalized [NUMERICAL]
# 	74 : DependenceVariance [NUMERICAL]
#
# Attribute in nodes with depth <= 5:
# 	502 : HighGrayLevelEmphasis [NUMERICAL]
# 	475 : LargeDependenceHighGrayLevelEmphasis [NUMERICAL]
# 	382 : DependenceEntropy [NUMERICAL]
# 	280 : LowGrayLevelEmphasis [NUMERICAL]
# 	265 : SmallDependenceHighGrayLevelEmphasis [NUMERICAL]
# 	242 : GrayLevelNonUniformity [NUMERICAL]
# 	239 : GrayLevelVariance [NUMERICAL]
# 	201 : SmallDependenceLowGrayLevelEmphasis [NUMERICAL]
# 	195 : LargeDependenceLowGrayLevelEmphasis [NUMERICAL]
# 	167 : SmallDependenceEmphasis [NUMERICAL]
# 	139 : DependenceNonUniformity [NUMERICAL]
# 	120 : DependenceNonUniformityNormalized [NUMERICAL]
# 	117 : LargeDependenceEmphasis [NUMERICAL]
# 	112 : DependenceVariance [NUMERICAL]
#
# Condition type in nodes:
# 	3558 : HigherCondition
# Condition type in nodes with depth <= 0:
# 	300 : HigherCondition
# Condition type in nodes with depth <= 1:
# 	894 : HigherCondition
# Condition type in nodes with depth <= 2:
# 	1780 : HigherCondition
# Condition type in nodes with depth <= 3:
# 	2636 : HigherCondition
# Condition type in nodes with depth <= 5:
# 	3436 : HigherCondition
# Node format: NOT_SET
#
# Training OOB:
# 	trees: 1, Out-of-bag evaluation: accuracy:0.914456 logloss:3.08331
# 	trees: 12, Out-of-bag evaluation: accuracy:0.91684 logloss:3.00056
# 	trees: 22, Out-of-bag evaluation: accuracy:0.914891 logloss:1.42643
# 	trees: 32, Out-of-bag evaluation: accuracy:0.917495 logloss:0.750538
# 	trees: 42, Out-of-bag evaluation: accuracy:0.917495 logloss:0.500714
# 	trees: 52, Out-of-bag evaluation: accuracy:0.923769 logloss:0.51
# 	trees: 62, Out-of-bag evaluation: accuracy:0.925071 logloss:0.510364
# 	trees: 72, Out-of-bag evaluation: accuracy:0.925071 logloss:0.507239
# 	trees: 82, Out-of-bag evaluation: accuracy:0.925071 logloss:0.256312
# 	trees: 92, Out-of-bag evaluation: accuracy:0.90992 logloss:0.254528
# 	trees: 104, Out-of-bag evaluation: accuracy:0.917495 logloss:0.259057
# 	trees: 114, Out-of-bag evaluation: accuracy:0.917495 logloss:0.255796
# 	trees: 126, Out-of-bag evaluation: accuracy:0.917495 logloss:0.256161
# 	trees: 136, Out-of-bag evaluation: accuracy:0.90992 logloss:0.217734
# 	trees: 146, Out-of-bag evaluation: accuracy:0.90992 logloss:0.219537
# 	trees: 156, Out-of-bag evaluation: accuracy:0.917495 logloss:0.218091
# 	trees: 166, Out-of-bag evaluation: accuracy:0.917495 logloss:0.217598
# 	trees: 176, Out-of-bag evaluation: accuracy:0.917495 logloss:0.213651
# 	trees: 186, Out-of-bag evaluation: accuracy:0.917495 logloss:0.210725
# 	trees: 196, Out-of-bag evaluation: accuracy:0.917495 logloss:0.210671
# 	trees: 206, Out-of-bag evaluation: accuracy:0.917495 logloss:0.211689
# 	trees: 217, Out-of-bag evaluation: accuracy:0.917495 logloss:0.211758
# 	trees: 227, Out-of-bag evaluation: accuracy:0.925071 logloss:0.211078
# 	trees: 237, Out-of-bag evaluation: accuracy:0.917495 logloss:0.211797
# 	trees: 248, Out-of-bag evaluation: accuracy:0.917495 logloss:0.212417
# 	trees: 259, Out-of-bag evaluation: accuracy:0.917495 logloss:0.214316
# 	trees: 269, Out-of-bag evaluation: accuracy:0.917495 logloss:0.215127
# 	trees: 279, Out-of-bag evaluation: accuracy:0.917495 logloss:0.212226
# 	trees: 290, Out-of-bag evaluation: accuracy:0.917495 logloss:0.213609
# 	trees: 300, Out-of-bag evaluation: accuracy:0.917495 logloss:0.21427

# %%
# Model features
model.make_inspector().features()
# Out:
# ["DependenceEntropy" (1; #0),
#  "DependenceNonUniformity" (1; #1),
#  "DependenceNonUniformityNormalized" (1; #2),
#  "DependenceVariance" (1; #3),
#  "GrayLevelNonUniformity" (1; #4),
#  "GrayLevelVariance" (1; #5),
#  "HighGrayLevelEmphasis" (1; #6),
#  "LargeDependenceEmphasis" (1; #7),
#  "LargeDependenceHighGrayLevelEmphasis" (1; #8),
#  "LargeDependenceLowGrayLevelEmphasis" (1; #9),
#  "LowGrayLevelEmphasis" (1; #10),
#  "SmallDependenceEmphasis" (1; #11),
#  "SmallDependenceHighGrayLevelEmphasis" (1; #12),
#  "SmallDependenceLowGrayLevelEmphasis" (1; #13)]

# %%
# Feature importance
model.make_inspector().variable_importances()
# Out:
# {'INV_MEAN_MIN_DEPTH': [("HighGrayLevelEmphasis" (1; #6), 0.32573313349839117),
#   ("LargeDependenceHighGrayLevelEmphasis" (1; #8), 0.3110765669603046),
#   ("LowGrayLevelEmphasis" (1; #10), 0.2509465130660299),
#   ("DependenceEntropy" (1; #0), 0.24405445965122774),
#   ("SmallDependenceLowGrayLevelEmphasis" (1; #13), 0.22719713138666167),
#   ("SmallDependenceHighGrayLevelEmphasis" (1; #12), 0.22505170727572185),
#   ("LargeDependenceLowGrayLevelEmphasis" (1; #9), 0.21968747957672202),
#   ("GrayLevelNonUniformity" (1; #4), 0.21660116178659172),
#   ("GrayLevelVariance" (1; #5), 0.21113097167581396),
#   ("SmallDependenceEmphasis" (1; #11), 0.2040362947324565),
#   ("LargeDependenceEmphasis" (1; #7), 0.20322244097409795),
#   ("DependenceNonUniformity" (1; #1), 0.20289756508167753),
#   ("DependenceNonUniformityNormalized" (1; #2), 0.2010852537338037),
#   ("DependenceVariance" (1; #3), 0.2007538353198192)],
#  'SUM_SCORE': [("HighGrayLevelEmphasis" (1; #6), 22610.991302377504),
#   ("LargeDependenceHighGrayLevelEmphasis" (1; #8), 19299.705593166964),
#   ("LowGrayLevelEmphasis" (1; #10), 10904.704783228406),
#   ("DependenceEntropy" (1; #0), 9074.385867737818),
#   ("SmallDependenceLowGrayLevelEmphasis" (1; #13), 5004.382308458601),
#   ("LargeDependenceLowGrayLevelEmphasis" (1; #9), 3973.5839704077766),
#   ("SmallDependenceHighGrayLevelEmphasis" (1; #12), 3879.6575546685976),
#   ("GrayLevelNonUniformity" (1; #4), 3590.654227274214),
#   ("GrayLevelVariance" (1; #5), 2770.0358708525587),
#   ("SmallDependenceEmphasis" (1; #11), 1600.3782289905105),
#   ("DependenceNonUniformity" (1; #1), 1314.1467677503567),
#   ("DependenceNonUniformityNormalized" (1; #2), 1125.122921137289),
#   ("LargeDependenceEmphasis" (1; #7), 1066.2933293989665),
#   ("DependenceVariance" (1; #3), 947.8347863923425)],
#  'NUM_AS_ROOT': [("HighGrayLevelEmphasis" (1; #6), 90.0),
#   ("LargeDependenceHighGrayLevelEmphasis" (1; #8), 77.0),
#   ("LowGrayLevelEmphasis" (1; #10), 54.0),
#   ("SmallDependenceLowGrayLevelEmphasis" (1; #13), 31.0),
#   ("LargeDependenceLowGrayLevelEmphasis" (1; #9), 23.0),
#   ("SmallDependenceHighGrayLevelEmphasis" (1; #12), 14.0),
#   ("DependenceEntropy" (1; #0), 6.0),
#   ("GrayLevelNonUniformity" (1; #4), 3.0),
#   ("DependenceVariance" (1; #3), 1.0),
#   ("LargeDependenceEmphasis" (1; #7), 1.0)],
#  'NUM_NODES': [("HighGrayLevelEmphasis" (1; #6), 511.0),
#   ("LargeDependenceHighGrayLevelEmphasis" (1; #8), 489.0),
#   ("DependenceEntropy" (1; #0), 396.0),
#   ("LowGrayLevelEmphasis" (1; #10), 289.0),
#   ("SmallDependenceHighGrayLevelEmphasis" (1; #12), 271.0),
#   ("GrayLevelNonUniformity" (1; #4), 252.0),
#   ("GrayLevelVariance" (1; #5), 247.0),
#   ("SmallDependenceLowGrayLevelEmphasis" (1; #13), 209.0),
#   ("LargeDependenceLowGrayLevelEmphasis" (1; #9), 202.0),
#   ("SmallDependenceEmphasis" (1; #11), 173.0),
#   ("DependenceNonUniformity" (1; #1), 150.0),
#   ("DependenceNonUniformityNormalized" (1; #2), 125.0),
#   ("DependenceVariance" (1; #3), 125.0),
#   ("LargeDependenceEmphasis" (1; #7), 119.0)]}

# %%
# Model self evaluation
model.make_inspector().evaluation()
# Out:
# Evaluation(num_examples=450, accuracy=0.9174952644666639, loss=0.21427002770424547, rmse=None, ndcg=None, aucs=None, auuc=None, qini=None)

# %%
logs = model.make_inspector().training_logs()

plt.figure(figsize=(12, 4))
plt.subplot(1, 2, 1)
plt.plot([log.num_trees for log in logs], [log.evaluation.accuracy for log in logs])
plt.xlabel("Number of trees")
plt.ylabel("Accuracy (out-of-bag)")
plt.subplot(1, 2, 2)
plt.plot([log.num_trees for log in logs], [log.evaluation.loss for log in logs])
plt.xlabel("Number of trees")
plt.ylabel("Logloss (out-of-bag)")
plt.show()

# %% [markdown]
# Calculate the score of our hold-out validation dataset

# %%
predictions = model.predict(val_ds)
y_true      = validation_data["label"]

from sklearn.metrics import roc_auc_score
ROC_AUC = roc_auc_score(y_true, predictions)
print("The ROC AUC score is %.5f" % ROC_AUC )
# Out:
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 58ms/step
# The ROC AUC score is 0.99630

# %%
# Compute binary classification metrics with sklearn
import numpy as np
from sklearn.metrics import (
    accuracy_score,
    precision_score,
    recall_score,
    f1_score,
    roc_auc_score,
    average_precision_score,
    confusion_matrix,
    classification_report,
    matthews_corrcoef,
    log_loss,
    brier_score_loss,
)

# Get predictions (probabilities or class labels)
preds = model.predict(test_ds)
# If model outputs probabilities, convert to labels by threshold 0.5
if preds.ndim == 2:
    # For TFDF classification, preds may be class probabilities with shape (N, 2)
    if preds.shape[1] == 2:
        pos_probs = preds[:, 1]
    else:
        # If single-probability column (positive class)
        pos_probs = preds[:, -1]
    y_pred = (pos_probs >= 0.5).astype(int)
else:
    # Already class labels
    y_pred = preds.astype(int)
    pos_probs = None

# Ground truth labels (must be 0/1 integers)
y_true = test_data["label"].astype(int).to_numpy()

# Core metrics
metrics = {}
metrics["accuracy"] = accuracy_score(y_true, y_pred)
metrics["precision"] = precision_score(y_true, y_pred, zero_division=0)
metrics["recall"] = recall_score(y_true, y_pred, zero_division=0)
metrics["f1"] = f1_score(y_true, y_pred, zero_division=0)
metrics["mcc"] = matthews_corrcoef(y_true, y_pred)

# Probabilistic metrics (only if we have probabilities)
if pos_probs is not None:
    metrics["roc_auc"] = roc_auc_score(y_true, pos_probs)
    metrics["pr_auc"] = average_precision_score(y_true, pos_probs)
    metrics["log_loss"] = log_loss(y_true, pos_probs, labels=[0,1])
    metrics["brier_score"] = brier_score_loss(y_true, pos_probs)

# Confusion matrix and detailed report
cm = confusion_matrix(y_true, y_pred, labels=[0,1])
report = classification_report(y_true, y_pred, digits=4)

print("Sklearn binary metrics:")
for k, v in metrics.items():
    print(f"{k}: {v:.4f}")
print("\nConfusion matrix:\n", cm)
print("\nClassification report:\n", report)
# Out:
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 61ms/step
# Sklearn binary metrics:
# accuracy: 0.9380
# precision: 0.6500
# recall: 0.9286
# f1: 0.7647
# mcc: 0.7457
# roc_auc: 0.9798
# pr_auc: 0.8824
# log_loss: 0.1346
# brier_score: 0.0377
#
# Confusion matrix:
#  [[108   7]
#  [  1  13]]
#
# Classification report:
#                precision    recall  f1-score   support
#
#            0     0.9908    0.9391    0.9643       115
#            1     0.6500    0.9286    0.7647        14
#
#     accuracy                         0.9380       129
#    macro avg     0.8204    0.9339    0.8645       129
# weighted avg     0.9538    0.9380    0.9426       129
