# %%
# Import packages and modules
import numpy  as np
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow_decision_forests as tfdf

from sklearn.model_selection import train_test_split
# Out:
# 2026-08-13 04:27:02.841230: I tensorflow/core/util/port.cc:113] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2026-08-13 04:27:03.220909: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2026-08-13 04:27:08.357867: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
# Check the version of TensorFlow Decision Forests
print("Found TensorFlow Decision Forests v" + tfdf.__version__)
# Out:
# Found TensorFlow Decision Forests v1.9.1

# %%
datasetPath = 'dataset/firstorder/kernel5/dataset.csv'

# %%
# Parameters
datasetPath = "dataset/gldm/kernel5/1.dataset.csv"

# %%
# train/validation/test = 70/10/20
dataset = pd.read_csv(datasetPath)

train_data, temp_data = train_test_split(dataset, test_size=0.3, random_state=42)
validation_data, test_data = train_test_split(temp_data, test_size=2/3, random_state=42)

# %%
from sklearn.utils.class_weight import compute_class_weight

# tinh class weight tren tap train
classes = np.array([0, 1])
weights = compute_class_weight(class_weight="balanced", classes=classes, y=train_data["label"])
class_weight = {0: weights[0], 1: weights[1]}

# gan sample_weight cho tung dong
train_data["sample_weight"] = train_data["label"].map(class_weight)
validation_data["sample_weight"] = validation_data["label"].map(class_weight)
test_data["sample_weight"] = test_data["label"].map(class_weight)

# Convert the dataset into a TensorFlow dataset.
train_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    train_data, label="label", weight="sample_weight"
)         
val_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    validation_data, label="label", weight="sample_weight"
)
test_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    test_data, label="label", weight="sample_weight"
)
# Out:
# 2026-08-13 04:27:22.379105: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:984] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2026-08-13 04:27:22.380529: W tensorflow/core/common_runtime/gpu/gpu_device.cc:2251] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...

# %%
import keras

# %%
# %%time

# Train a Random Forest model.
model = tfdf.keras.RandomForestModel()

# Add evaluation metrics
model.compile(
    metrics=["accuracy"]
)
model.fit(x=train_ds)

# # Train a Gradient Boosted Trees model.
# model = tfdf.keras.GradientBoostedTreesModel(num_trees=1500)
# model.fit(train_ds)
# Out:
# Use /tmp/tmpc5mb9usq as temporary training directory
# Reading training dataset...
# Training dataset read in 0:00:02.627027. Found 737 examples.
# Training model...
# Model trained in 0:00:00.069145
# Compiling model...
# [INFO 26-08-13 04:27:25.2300 UTC kernel.cc:1233] Loading model from path /tmp/tmpc5mb9usq/model/ with prefix d741c90a93b74ad0
# [INFO 26-08-13 04:27:25.2439 UTC decision_forest.cc:734] Model loaded with 300 root(s), 11308 node(s), and 14 input feature(s).
# [INFO 26-08-13 04:27:25.2439 UTC abstract_model.cc:1362] Engine "RandomForestOptPred" built
# [INFO 26-08-13 04:27:25.2439 UTC kernel.cc:1061] Use fast generic engine
# Model compiled.
# CPU times: user 5.5 s, sys: 167 ms, total: 5.66 s
# Wall time: 5.95 s

# %%
# Evaluate the model
evaluate = model.evaluate(val_ds, return_dict=True)
print()

for name, value in evaluate.items():
    print(f"{name}: {value:.4f}")
# Out:
# WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 1/1 [==============================] - ETA: 0s - loss: 0.0000e+00 - accuracy: 0.9619
# 1/1 [==============================] - 3s 3s/step - loss: 0.0000e+00 - accuracy: 0.9619
# loss: 0.0000
# accuracy: 0.9619

# %%
# Model Summary
model.summary()
# Out:
# Model: "random_forest_model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
# =================================================================
# Total params: 1 (1.00 Byte)
# Trainable params: 0 (0.00 Byte)
# Non-trainable params: 1 (1.00 Byte)
# _________________________________________________________________
# Type: "RANDOM_FOREST"
# Task: CLASSIFICATION
# Label: "__LABEL"
#
# Input Features (14):
# 	DependenceEntropy
# 	DependenceNonUniformity
# 	DependenceNonUniformityNormalized
# 	DependenceVariance
# 	GrayLevelNonUniformity
# 	GrayLevelVariance
# 	HighGrayLevelEmphasis
# 	LargeDependenceEmphasis
# 	LargeDependenceHighGrayLevelEmphasis
# 	LargeDependenceLowGrayLevelEmphasis
# 	LowGrayLevelEmphasis
# 	SmallDependenceEmphasis
# 	SmallDependenceHighGrayLevelEmphasis
# 	SmallDependenceLowGrayLevelEmphasis
#
# Trained with weights
#
# Variable Importance: INV_MEAN_MIN_DEPTH:
#     1.                "HighGrayLevelEmphasis"  0.364086 ################
#     2. "LargeDependenceHighGrayLevelEmphasis"  0.283740 #########
#     3.                 "LowGrayLevelEmphasis"  0.233838 ####
#     4.                    "DependenceEntropy"  0.208815 ##
#     5.  "SmallDependenceLowGrayLevelEmphasis"  0.204133 ##
#     6. "SmallDependenceHighGrayLevelEmphasis"  0.193031 #
#     7.  "LargeDependenceLowGrayLevelEmphasis"  0.184589
#     8.              "DependenceNonUniformity"  0.181631
#     9.                    "GrayLevelVariance"  0.179875
#    10.    "DependenceNonUniformityNormalized"  0.178783
#    11.               "GrayLevelNonUniformity"  0.176289
#    12.                   "DependenceVariance"  0.175870
#    13.              "LargeDependenceEmphasis"  0.175674
#    14.              "SmallDependenceEmphasis"  0.175252
#
# Variable Importance: NUM_AS_ROOT:
#     1.                "HighGrayLevelEmphasis" 118.000000 ################
#     2. "LargeDependenceHighGrayLevelEmphasis" 67.000000 #########
#     3.                 "LowGrayLevelEmphasis" 47.000000 ######
#     4.  "SmallDependenceLowGrayLevelEmphasis" 31.000000 ####
#     5.  "LargeDependenceLowGrayLevelEmphasis" 13.000000 #
#     6. "SmallDependenceHighGrayLevelEmphasis" 13.000000 #
#     7.                    "DependenceEntropy"  8.000000
#     8.                   "DependenceVariance"  2.000000
#     9.              "LargeDependenceEmphasis"  1.000000
#
# Variable Importance: NUM_NODES:
#     1.                "HighGrayLevelEmphasis" 740.000000 ################
#     2. "LargeDependenceHighGrayLevelEmphasis" 652.000000 #############
#     3.                    "DependenceEntropy" 589.000000 ###########
#     4.                 "LowGrayLevelEmphasis" 475.000000 #######
#     5.  "SmallDependenceLowGrayLevelEmphasis" 370.000000 ###
#     6. "SmallDependenceHighGrayLevelEmphasis" 356.000000 ###
#     7.               "GrayLevelNonUniformity" 344.000000 ###
#     8.  "LargeDependenceLowGrayLevelEmphasis" 338.000000 ##
#     9.                    "GrayLevelVariance" 323.000000 ##
#    10.              "LargeDependenceEmphasis" 277.000000
#    11.              "SmallDependenceEmphasis" 276.000000
#    12.              "DependenceNonUniformity" 268.000000
#    13.    "DependenceNonUniformityNormalized" 249.000000
#    14.                   "DependenceVariance" 247.000000
#
# Variable Importance: SUM_SCORE:
#     1.                "HighGrayLevelEmphasis" 52277.411058 ################
#     2. "LargeDependenceHighGrayLevelEmphasis" 28452.003008 ########
#     3.                 "LowGrayLevelEmphasis" 15992.311904 ####
#     4.                    "DependenceEntropy" 10470.548799 ##
#     5.  "SmallDependenceLowGrayLevelEmphasis" 8442.713487 ##
#     6. "SmallDependenceHighGrayLevelEmphasis" 5399.836138 #
#     7.  "LargeDependenceLowGrayLevelEmphasis" 4130.979682
#     8.                    "GrayLevelVariance" 3434.638622
#     9.               "GrayLevelNonUniformity" 3154.738171
#    10.              "DependenceNonUniformity" 2669.663809
#    11.    "DependenceNonUniformityNormalized" 2429.129776
#    12.              "LargeDependenceEmphasis" 2034.502482
#    13.              "SmallDependenceEmphasis" 1978.279655
#    14.                   "DependenceVariance" 1915.780033
#
#
#
# Winner takes all: true
# Out-of-bag evaluation: accuracy:0.913238 logloss:0.359276
# Number of trees: 300
# Total number of nodes: 11308
#
# Number of nodes by tree:
# Count: 300 Average: 37.6933 StdDev: 4.74123
# Min: 23 Max: 53 Ignored: 0
# ----------------------------------------------
# [ 23, 24)  1   0.33%   0.33%
# [ 24, 26)  1   0.33%   0.67%
# [ 26, 27)  0   0.00%   0.67%
# [ 27, 29)  4   1.33%   2.00% #
# [ 29, 30)  8   2.67%   4.67% #
# [ 30, 32) 23   7.67%  12.33% ####
# [ 32, 33)  0   0.00%  12.33%
# [ 33, 35) 28   9.33%  21.67% #####
# [ 35, 36) 40  13.33%  35.00% #######
# [ 36, 38) 55  18.33%  53.33% ##########
# [ 38, 40) 42  14.00%  67.33% ########
# [ 40, 41)  0   0.00%  67.33%
# [ 41, 43) 46  15.33%  82.67% ########
# [ 43, 44) 22   7.33%  90.00% ####
# [ 44, 46) 22   7.33%  97.33% ####
# [ 46, 47)  0   0.00%  97.33%
# [ 47, 49)  5   1.67%  99.00% #
# [ 49, 50)  1   0.33%  99.33%
# [ 50, 52)  1   0.33%  99.67%
# [ 52, 53]  1   0.33% 100.00%
#
# Depth by leafs:
# Count: 5804 Average: 5.11199 StdDev: 1.70888
# Min: 1 Max: 13 Ignored: 0
# ----------------------------------------------
# [  1,  2)    5   0.09%   0.09%
# [  2,  3)  230   3.96%   4.05% ##
# [  3,  4)  776  13.37%  17.42% ######
# [  4,  5) 1254  21.61%  39.02% #########
# [  5,  6) 1335  23.00%  62.03% ##########
# [  6,  7) 1042  17.95%  79.98% ########
# [  7,  8)  654  11.27%  91.25% #####
# [  8,  9)  308   5.31%  96.55% ##
# [  9, 10)  129   2.22%  98.78% #
# [ 10, 11)   55   0.95%  99.72%
# [ 11, 12)   13   0.22%  99.95%
# [ 12, 13)    1   0.02%  99.97%
# [ 13, 13]    2   0.03% 100.00%
#
# Number of training obs by leaf:
# Count: 5804 Average: 38.0944 StdDev: 88.5343
# Min: 5 Max: 551 Ignored: 0
# ----------------------------------------------
# [   5,  32) 4623  79.65%  79.65% ##########
# [  32,  59)  498   8.58%  88.23% #
# [  59,  87)  194   3.34%  91.57%
# [  87, 114)   57   0.98%  92.56%
# [ 114, 141)   32   0.55%  93.11%
# [ 141, 169)   51   0.88%  93.99%
# [ 169, 196)   23   0.40%  94.38%
# [ 196, 223)   23   0.40%  94.78%
# [ 223, 251)   17   0.29%  95.07%
# [ 251, 278)   12   0.21%  95.28%
# [ 278, 305)   19   0.33%  95.61%
# [ 305, 333)   38   0.65%  96.26%
# [ 333, 360)   25   0.43%  96.69%
# [ 360, 387)   28   0.48%  97.17%
# [ 387, 415)   38   0.65%  97.83%
# [ 415, 442)   43   0.74%  98.57%
# [ 442, 469)   36   0.62%  99.19%
# [ 469, 497)   21   0.36%  99.55%
# [ 497, 524)   21   0.36%  99.91%
# [ 524, 551]    5   0.09% 100.00%
#
# Attribute in nodes:
# 	740 : HighGrayLevelEmphasis [NUMERICAL]
# 	652 : LargeDependenceHighGrayLevelEmphasis [NUMERICAL]
# 	589 : DependenceEntropy [NUMERICAL]
# 	475 : LowGrayLevelEmphasis [NUMERICAL]
# 	370 : SmallDependenceLowGrayLevelEmphasis [NUMERICAL]
# 	356 : SmallDependenceHighGrayLevelEmphasis [NUMERICAL]
# 	344 : GrayLevelNonUniformity [NUMERICAL]
# 	338 : LargeDependenceLowGrayLevelEmphasis [NUMERICAL]
# 	323 : GrayLevelVariance [NUMERICAL]
# 	277 : LargeDependenceEmphasis [NUMERICAL]
# 	276 : SmallDependenceEmphasis [NUMERICAL]
# 	268 : DependenceNonUniformity [NUMERICAL]
# 	249 : DependenceNonUniformityNormalized [NUMERICAL]
# 	247 : DependenceVariance [NUMERICAL]
#
# Attribute in nodes with depth <= 0:
# 	118 : HighGrayLevelEmphasis [NUMERICAL]
# 	67 : LargeDependenceHighGrayLevelEmphasis [NUMERICAL]
# 	47 : LowGrayLevelEmphasis [NUMERICAL]
# 	31 : SmallDependenceLowGrayLevelEmphasis [NUMERICAL]
# 	13 : SmallDependenceHighGrayLevelEmphasis [NUMERICAL]
# 	13 : LargeDependenceLowGrayLevelEmphasis [NUMERICAL]
# 	8 : DependenceEntropy [NUMERICAL]
# 	2 : DependenceVariance [NUMERICAL]
# 	1 : LargeDependenceEmphasis [NUMERICAL]
#
# Attribute in nodes with depth <= 1:
# 	266 : HighGrayLevelEmphasis [NUMERICAL]
# 	163 : LargeDependenceHighGrayLevelEmphasis [NUMERICAL]
# 	128 : LowGrayLevelEmphasis [NUMERICAL]
# 	81 : DependenceEntropy [NUMERICAL]
# 	72 : SmallDependenceLowGrayLevelEmphasis [NUMERICAL]
# 	58 : SmallDependenceHighGrayLevelEmphasis [NUMERICAL]
# 	35 : LargeDependenceLowGrayLevelEmphasis [NUMERICAL]
# 	29 : GrayLevelVariance [NUMERICAL]
# 	15 : GrayLevelNonUniformity [NUMERICAL]
# 	14 : DependenceNonUniformityNormalized [NUMERICAL]
# 	13 : DependenceNonUniformity [NUMERICAL]
# 	8 : LargeDependenceEmphasis [NUMERICAL]
# 	7 : SmallDependenceEmphasis [NUMERICAL]
# 	6 : DependenceVariance [NUMERICAL]
#
# Attribute in nodes with depth <= 2:
# 	414 : HighGrayLevelEmphasis [NUMERICAL]
# 	310 : LargeDependenceHighGrayLevelEmphasis [NUMERICAL]
# 	217 : LowGrayLevelEmphasis [NUMERICAL]
# 	214 : DependenceEntropy [NUMERICAL]
# 	124 : SmallDependenceLowGrayLevelEmphasis [NUMERICAL]
# 	107 : SmallDependenceHighGrayLevelEmphasis [NUMERICAL]
# 	82 : GrayLevelVariance [NUMERICAL]
# 	65 : GrayLevelNonUniformity [NUMERICAL]
# 	63 : LargeDependenceLowGrayLevelEmphasis [NUMERICAL]
# 	61 : DependenceNonUniformity [NUMERICAL]
# 	56 : DependenceNonUniformityNormalized [NUMERICAL]
# 	49 : SmallDependenceEmphasis [NUMERICAL]
# 	47 : LargeDependenceEmphasis [NUMERICAL]
# 	46 : DependenceVariance [NUMERICAL]
#
# Attribute in nodes with depth <= 3:
# 	545 : HighGrayLevelEmphasis [NUMERICAL]
# 	455 : LargeDependenceHighGrayLevelEmphasis [NUMERICAL]
# 	339 : DependenceEntropy [NUMERICAL]
# 	303 : LowGrayLevelEmphasis [NUMERICAL]
# 	192 : SmallDependenceLowGrayLevelEmphasis [NUMERICAL]
# 	170 : SmallDependenceHighGrayLevelEmphasis [NUMERICAL]
# 	156 : GrayLevelVariance [NUMERICAL]
# 	151 : GrayLevelNonUniformity [NUMERICAL]
# 	133 : DependenceNonUniformity [NUMERICAL]
# 	128 : LargeDependenceLowGrayLevelEmphasis [NUMERICAL]
# 	117 : LargeDependenceEmphasis [NUMERICAL]
# 	107 : SmallDependenceEmphasis [NUMERICAL]
# 	107 : DependenceNonUniformityNormalized [NUMERICAL]
# 	96 : DependenceVariance [NUMERICAL]
#
# Attribute in nodes with depth <= 5:
# 	686 : HighGrayLevelEmphasis [NUMERICAL]
# 	605 : LargeDependenceHighGrayLevelEmphasis [NUMERICAL]
# 	532 : DependenceEntropy [NUMERICAL]
# 	411 : LowGrayLevelEmphasis [NUMERICAL]
# 	324 : SmallDependenceLowGrayLevelEmphasis [NUMERICAL]
# 	296 : SmallDependenceHighGrayLevelEmphasis [NUMERICAL]
# 	279 : GrayLevelNonUniformity [NUMERICAL]
# 	277 : LargeDependenceLowGrayLevelEmphasis [NUMERICAL]
# 	265 : GrayLevelVariance [NUMERICAL]
# 	239 : DependenceNonUniformity [NUMERICAL]
# 	225 : LargeDependenceEmphasis [NUMERICAL]
# 	224 : SmallDependenceEmphasis [NUMERICAL]
# 	204 : DependenceNonUniformityNormalized [NUMERICAL]
# 	199 : DependenceVariance [NUMERICAL]
#
# Condition type in nodes:
# 	5504 : HigherCondition
# Condition type in nodes with depth <= 0:
# 	300 : HigherCondition
# Condition type in nodes with depth <= 1:
# 	895 : HigherCondition
# Condition type in nodes with depth <= 2:
# 	1855 : HigherCondition
# Condition type in nodes with depth <= 3:
# 	2999 : HigherCondition
# Condition type in nodes with depth <= 5:
# 	4766 : HigherCondition
# Node format: NOT_SET
#
# Training OOB:
# 	trees: 1, Out-of-bag evaluation: accuracy:0.863308 logloss:4.92689
# 	trees: 12, Out-of-bag evaluation: accuracy:0.87556 logloss:2.50749
# 	trees: 22, Out-of-bag evaluation: accuracy:0.917225 logloss:0.957749
# 	trees: 33, Out-of-bag evaluation: accuracy:0.908134 logloss:0.88166
# 	trees: 43, Out-of-bag evaluation: accuracy:0.920175 logloss:0.729699
# 	trees: 54, Out-of-bag evaluation: accuracy:0.916427 logloss:0.732223
# 	trees: 64, Out-of-bag evaluation: accuracy:0.920973 logloss:0.735092
# 	trees: 75, Out-of-bag evaluation: accuracy:0.930064 logloss:0.708998
# 	trees: 85, Out-of-bag evaluation: accuracy:0.933014 logloss:0.708418
# 	trees: 95, Out-of-bag evaluation: accuracy:0.917783 logloss:0.683476
# 	trees: 105, Out-of-bag evaluation: accuracy:0.922329 logloss:0.680845
# 	trees: 115, Out-of-bag evaluation: accuracy:0.917783 logloss:0.681514
# 	trees: 126, Out-of-bag evaluation: accuracy:0.922329 logloss:0.680248
# 	trees: 137, Out-of-bag evaluation: accuracy:0.922329 logloss:0.508906
# 	trees: 147, Out-of-bag evaluation: accuracy:0.917783 logloss:0.505008
# 	trees: 159, Out-of-bag evaluation: accuracy:0.926874 logloss:0.50391
# 	trees: 169, Out-of-bag evaluation: accuracy:0.926874 logloss:0.504722
# 	trees: 179, Out-of-bag evaluation: accuracy:0.926874 logloss:0.50385
# 	trees: 189, Out-of-bag evaluation: accuracy:0.926874 logloss:0.504794
# 	trees: 199, Out-of-bag evaluation: accuracy:0.926874 logloss:0.35815
# 	trees: 209, Out-of-bag evaluation: accuracy:0.922329 logloss:0.357998
# 	trees: 219, Out-of-bag evaluation: accuracy:0.922329 logloss:0.35849
# 	trees: 229, Out-of-bag evaluation: accuracy:0.922329 logloss:0.358201
# 	trees: 239, Out-of-bag evaluation: accuracy:0.922329 logloss:0.35897
# 	trees: 249, Out-of-bag evaluation: accuracy:0.922329 logloss:0.358582
# 	trees: 259, Out-of-bag evaluation: accuracy:0.922329 logloss:0.358301
# 	trees: 269, Out-of-bag evaluation: accuracy:0.917783 logloss:0.359847
# 	trees: 280, Out-of-bag evaluation: accuracy:0.917783 logloss:0.360046
# 	trees: 291, Out-of-bag evaluation: accuracy:0.913238 logloss:0.360736
# 	trees: 300, Out-of-bag evaluation: accuracy:0.913238 logloss:0.359276

# %%
# Model features
model.make_inspector().features()
# Out:
# ["DependenceEntropy" (1; #0),
#  "DependenceNonUniformity" (1; #1),
#  "DependenceNonUniformityNormalized" (1; #2),
#  "DependenceVariance" (1; #3),
#  "GrayLevelNonUniformity" (1; #4),
#  "GrayLevelVariance" (1; #5),
#  "HighGrayLevelEmphasis" (1; #6),
#  "LargeDependenceEmphasis" (1; #7),
#  "LargeDependenceHighGrayLevelEmphasis" (1; #8),
#  "LargeDependenceLowGrayLevelEmphasis" (1; #9),
#  "LowGrayLevelEmphasis" (1; #10),
#  "SmallDependenceEmphasis" (1; #11),
#  "SmallDependenceHighGrayLevelEmphasis" (1; #12),
#  "SmallDependenceLowGrayLevelEmphasis" (1; #13)]

# %%
# Feature importance
model.make_inspector().variable_importances()
# Out:
# {'INV_MEAN_MIN_DEPTH': [("HighGrayLevelEmphasis" (1; #6), 0.36408612580884286),
#   ("LargeDependenceHighGrayLevelEmphasis" (1; #8), 0.28374002605205273),
#   ("LowGrayLevelEmphasis" (1; #10), 0.2338381066250127),
#   ("DependenceEntropy" (1; #0), 0.208815295457078),
#   ("SmallDependenceLowGrayLevelEmphasis" (1; #13), 0.2041325839858136),
#   ("SmallDependenceHighGrayLevelEmphasis" (1; #12), 0.1930308345220526),
#   ("LargeDependenceLowGrayLevelEmphasis" (1; #9), 0.18458909893348377),
#   ("DependenceNonUniformity" (1; #1), 0.18163080194098058),
#   ("GrayLevelVariance" (1; #5), 0.17987481361314953),
#   ("DependenceNonUniformityNormalized" (1; #2), 0.1787830034819025),
#   ("GrayLevelNonUniformity" (1; #4), 0.17628889097017517),
#   ("DependenceVariance" (1; #3), 0.17587012161723103),
#   ("LargeDependenceEmphasis" (1; #7), 0.17567383797044236),
#   ("SmallDependenceEmphasis" (1; #11), 0.1752523810230306)],
#  'NUM_AS_ROOT': [("HighGrayLevelEmphasis" (1; #6), 118.0),
#   ("LargeDependenceHighGrayLevelEmphasis" (1; #8), 67.0),
#   ("LowGrayLevelEmphasis" (1; #10), 47.0),
#   ("SmallDependenceLowGrayLevelEmphasis" (1; #13), 31.0),
#   ("LargeDependenceLowGrayLevelEmphasis" (1; #9), 13.0),
#   ("SmallDependenceHighGrayLevelEmphasis" (1; #12), 13.0),
#   ("DependenceEntropy" (1; #0), 8.0),
#   ("DependenceVariance" (1; #3), 2.0),
#   ("LargeDependenceEmphasis" (1; #7), 1.0)],
#  'SUM_SCORE': [("HighGrayLevelEmphasis" (1; #6), 52277.411057755744),
#   ("LargeDependenceHighGrayLevelEmphasis" (1; #8), 28452.003007893432),
#   ("LowGrayLevelEmphasis" (1; #10), 15992.311904047354),
#   ("DependenceEntropy" (1; #0), 10470.548799017024),
#   ("SmallDependenceLowGrayLevelEmphasis" (1; #13), 8442.71348682286),
#   ("SmallDependenceHighGrayLevelEmphasis" (1; #12), 5399.836137804635),
#   ("LargeDependenceLowGrayLevelEmphasis" (1; #9), 4130.9796821470345),
#   ("GrayLevelVariance" (1; #5), 3434.6386221967377),
#   ("GrayLevelNonUniformity" (1; #4), 3154.7381709854853),
#   ("DependenceNonUniformity" (1; #1), 2669.663809140058),
#   ("DependenceNonUniformityNormalized" (1; #2), 2429.129776351084),
#   ("LargeDependenceEmphasis" (1; #7), 2034.5024822831294),
#   ("SmallDependenceEmphasis" (1; #11), 1978.2796551222027),
#   ("DependenceVariance" (1; #3), 1915.780032834658)],
#  'NUM_NODES': [("HighGrayLevelEmphasis" (1; #6), 740.0),
#   ("LargeDependenceHighGrayLevelEmphasis" (1; #8), 652.0),
#   ("DependenceEntropy" (1; #0), 589.0),
#   ("LowGrayLevelEmphasis" (1; #10), 475.0),
#   ("SmallDependenceLowGrayLevelEmphasis" (1; #13), 370.0),
#   ("SmallDependenceHighGrayLevelEmphasis" (1; #12), 356.0),
#   ("GrayLevelNonUniformity" (1; #4), 344.0),
#   ("LargeDependenceLowGrayLevelEmphasis" (1; #9), 338.0),
#   ("GrayLevelVariance" (1; #5), 323.0),
#   ("LargeDependenceEmphasis" (1; #7), 277.0),
#   ("SmallDependenceEmphasis" (1; #11), 276.0),
#   ("DependenceNonUniformity" (1; #1), 268.0),
#   ("DependenceNonUniformityNormalized" (1; #2), 249.0),
#   ("DependenceVariance" (1; #3), 247.0)]}

# %%
# Model self evaluation
model.make_inspector().evaluation()
# Out:
# Evaluation(num_examples=737, accuracy=0.913237640922907, loss=0.35927648117595634, rmse=None, ndcg=None, aucs=None, auuc=None, qini=None)

# %%
logs = model.make_inspector().training_logs()

plt.figure(figsize=(12, 4))
plt.subplot(1, 2, 1)
plt.plot([log.num_trees for log in logs], [log.evaluation.accuracy for log in logs])
plt.xlabel("Number of trees")
plt.ylabel("Accuracy (out-of-bag)")
plt.subplot(1, 2, 2)
plt.plot([log.num_trees for log in logs], [log.evaluation.loss for log in logs])
plt.xlabel("Number of trees")
plt.ylabel("Logloss (out-of-bag)")
plt.show()

# %% [markdown]
# Calculate the score of our hold-out validation dataset

# %%
predictions = model.predict(val_ds)
y_true      = validation_data["label"]

from sklearn.metrics import roc_auc_score
ROC_AUC = roc_auc_score(y_true, predictions)
print("The ROC AUC score is %.5f" % ROC_AUC )
# Out:
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 59ms/step
# The ROC AUC score is 0.98495

# %%
# Compute binary classification metrics with sklearn
import numpy as np
from sklearn.metrics import (
    accuracy_score,
    precision_score,
    recall_score,
    f1_score,
    roc_auc_score,
    average_precision_score,
    confusion_matrix,
    classification_report,
    matthews_corrcoef,
    log_loss,
    brier_score_loss,
)

# Get predictions (probabilities or class labels)
preds = model.predict(test_ds)
# If model outputs probabilities, convert to labels by threshold 0.5
if preds.ndim == 2:
    # For TFDF classification, preds may be class probabilities with shape (N, 2)
    if preds.shape[1] == 2:
        pos_probs = preds[:, 1]
    else:
        # If single-probability column (positive class)
        pos_probs = preds[:, -1]
    y_pred = (pos_probs >= 0.5).astype(int)
else:
    # Already class labels
    y_pred = preds.astype(int)
    pos_probs = None

# Ground truth labels (must be 0/1 integers)
y_true = test_data["label"].astype(int).to_numpy()

# Core metrics
metrics = {}
metrics["accuracy"] = accuracy_score(y_true, y_pred)
metrics["precision"] = precision_score(y_true, y_pred, zero_division=0)
metrics["recall"] = recall_score(y_true, y_pred, zero_division=0)
metrics["f1"] = f1_score(y_true, y_pred, zero_division=0)
metrics["mcc"] = matthews_corrcoef(y_true, y_pred)

# Probabilistic metrics (only if we have probabilities)
if pos_probs is not None:
    metrics["roc_auc"] = roc_auc_score(y_true, pos_probs)
    metrics["pr_auc"] = average_precision_score(y_true, pos_probs)
    metrics["log_loss"] = log_loss(y_true, pos_probs, labels=[0,1])
    metrics["brier_score"] = brier_score_loss(y_true, pos_probs)

# Confusion matrix and detailed report
cm = confusion_matrix(y_true, y_pred, labels=[0,1])
report = classification_report(y_true, y_pred, digits=4)

print("Sklearn binary metrics:")
for k, v in metrics.items():
    print(f"{k}: {v:.4f}")
print("\nConfusion matrix:\n", cm)
print("\nClassification report:\n", report)
# Out:
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 78ms/step
# Sklearn binary metrics:
# accuracy: 0.9528
# precision: 0.6818
# recall: 0.8333
# f1: 0.7500
# mcc: 0.7287
# roc_auc: 0.9825
# pr_auc: 0.8852
# log_loss: 0.1025
# brier_score: 0.0298
#
# Confusion matrix:
#  [[187   7]
#  [  3  15]]
#
# Classification report:
#                precision    recall  f1-score   support
#
#            0     0.9842    0.9639    0.9740       194
#            1     0.6818    0.8333    0.7500        18
#
#     accuracy                         0.9528       212
#    macro avg     0.8330    0.8986    0.8620       212
# weighted avg     0.9585    0.9528    0.9549       212
