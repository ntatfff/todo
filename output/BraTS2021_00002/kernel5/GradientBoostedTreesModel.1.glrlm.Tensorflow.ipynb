# %%
# Import packages and modules
import numpy  as np
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow_decision_forests as tfdf

from sklearn.model_selection import train_test_split
# Out:
# 2026-08-13 04:16:21.511004: I tensorflow/core/util/port.cc:113] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2026-08-13 04:16:21.900144: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2026-08-13 04:16:26.657336: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
# Check the version of TensorFlow Decision Forests
print("Found TensorFlow Decision Forests v" + tfdf.__version__)
# Out:
# Found TensorFlow Decision Forests v1.9.1

# %%
datasetPath = 'dataset/firstorder/kernel5/dataset.csv'

# %%
# Parameters
datasetPath = "dataset/glrlm/kernel5/1.dataset.csv"

# %%
# train/validation/test = 70/10/20
dataset = pd.read_csv(datasetPath)

train_data, temp_data = train_test_split(dataset, test_size=0.3, random_state=42)
validation_data, test_data = train_test_split(temp_data, test_size=2/3, random_state=42)

# %%
from sklearn.utils.class_weight import compute_class_weight

# tinh class weight tren tap train
classes = np.array([0, 1])
weights = compute_class_weight(class_weight="balanced", classes=classes, y=train_data["label"])
class_weight = {0: weights[0], 1: weights[1]}

# gan sample_weight cho tung dong
train_data["sample_weight"] = train_data["label"].map(class_weight)
validation_data["sample_weight"] = validation_data["label"].map(class_weight)
test_data["sample_weight"] = test_data["label"].map(class_weight)

# Convert the dataset into a TensorFlow dataset.
train_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    train_data, label="label", weight="sample_weight"
)         
val_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    validation_data, label="label", weight="sample_weight"
)
test_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    test_data, label="label", weight="sample_weight"
)
# Out:
# 2026-08-13 04:16:41.062509: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:984] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2026-08-13 04:16:41.064212: W tensorflow/core/common_runtime/gpu/gpu_device.cc:2251] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...

# %%
import keras

# %%
# %%time

# Train a Gradient Boosted Trees model.
model = tfdf.keras.GradientBoostedTreesModel()

# Add evaluation metrics
model.compile(
    metrics=["accuracy"]
)
model.fit(x=train_ds)

# # Train a Gradient Boosted Trees model.
# model = tfdf.keras.GradientBoostedTreesModel(num_trees=1500)
# model.fit(train_ds)
# Out:
# Use /tmp/tmpud7m4e2y as temporary training directory
# Reading training dataset...
# [WARNING 26-08-13 04:16:41.2229 UTC gradient_boosted_trees.cc:1840] "goss_alpha" set but "sampling_method" not equal to "GOSS".
# [WARNING 26-08-13 04:16:41.2231 UTC gradient_boosted_trees.cc:1851] "goss_beta" set but "sampling_method" not equal to "GOSS".
# [WARNING 26-08-13 04:16:41.2231 UTC gradient_boosted_trees.cc:1865] "selective_gradient_boosting_ratio" set but "sampling_method" not equal to "SELGB".
# Training dataset read in 0:00:02.562339. Found 737 examples.
# Training model...
# Model trained in 0:00:00.220045
# Compiling model...
# [INFO 26-08-13 04:16:44.0345 UTC kernel.cc:1233] Loading model from path /tmp/tmpud7m4e2y/model/ with prefix b7e37a2df9084b1c
# [INFO 26-08-13 04:16:44.0364 UTC quick_scorer_extended.cc:911] The binary was compiled without AVX2 support, but your CPU supports it. Enable it for faster model inference.
# [INFO 26-08-13 04:16:44.0365 UTC abstract_model.cc:1362] Engine "GradientBoostedTreesQuickScorerExtended" built
# [INFO 26-08-13 04:16:44.0365 UTC kernel.cc:1061] Use fast generic engine
# Model compiled.
# CPU times: user 5.59 s, sys: 353 ms, total: 5.94 s
# Wall time: 5.94 s

# %%
# Evaluate the model
evaluate = model.evaluate(val_ds, return_dict=True)
print()

for name, value in evaluate.items():
    print(f"{name}: {value:.4f}")
# Out:
# WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 1/1 [==============================] - ETA: 0s - loss: 0.0000e+00 - accuracy: 0.9143
# 1/1 [==============================] - 3s 3s/step - loss: 0.0000e+00 - accuracy: 0.9143
# loss: 0.0000
# accuracy: 0.9143

# %%
# Model Summary
model.summary()
# Out:
# Model: "gradient_boosted_trees_model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
# =================================================================
# Total params: 1 (1.00 Byte)
# Trainable params: 0 (0.00 Byte)
# Non-trainable params: 1 (1.00 Byte)
# _________________________________________________________________
# Type: "GRADIENT_BOOSTED_TREES"
# Task: CLASSIFICATION
# Label: "__LABEL"
#
# Input Features (16):
# 	GrayLevelNonUniformity
# 	GrayLevelNonUniformityNormalized
# 	GrayLevelVariance
# 	HighGrayLevelRunEmphasis
# 	LongRunEmphasis
# 	LongRunHighGrayLevelEmphasis
# 	LongRunLowGrayLevelEmphasis
# 	LowGrayLevelRunEmphasis
# 	RunEntropy
# 	RunLengthNonUniformity
# 	RunLengthNonUniformityNormalized
# 	RunPercentage
# 	RunVariance
# 	ShortRunEmphasis
# 	ShortRunHighGrayLevelEmphasis
# 	ShortRunLowGrayLevelEmphasis
#
# Trained with weights
#
# Variable Importance: INV_MEAN_MIN_DEPTH:
#     1.     "LongRunHighGrayLevelEmphasis"  1.000000 ################
#     2.                       "RunEntropy"  0.230601
#     3.         "HighGrayLevelRunEmphasis"  0.201088
#     4.    "ShortRunHighGrayLevelEmphasis"  0.200260
#     5. "GrayLevelNonUniformityNormalized"  0.195506
#     6.      "LongRunLowGrayLevelEmphasis"  0.190415
#     7.          "LowGrayLevelRunEmphasis"  0.190330
#     8.                "GrayLevelVariance"  0.189847
#     9.     "ShortRunLowGrayLevelEmphasis"  0.189202
#    10.           "GrayLevelNonUniformity"  0.186742
#    11.                      "RunVariance"  0.182937
#    12.           "RunLengthNonUniformity"  0.182191
#    13.                 "ShortRunEmphasis"  0.181717
#    14.                    "RunPercentage"  0.181407
#    15. "RunLengthNonUniformityNormalized"  0.181401
#    16.                  "LongRunEmphasis"  0.180881
#
# Variable Importance: NUM_AS_ROOT:
#     1. "LongRunHighGrayLevelEmphasis" 24.000000
#
# Variable Importance: NUM_NODES:
#     1.     "LongRunHighGrayLevelEmphasis" 130.000000 ################
#     2.                       "RunEntropy" 83.000000 ##########
#     3.                "GrayLevelVariance" 37.000000 ####
#     4.         "HighGrayLevelRunEmphasis" 37.000000 ####
#     5.    "ShortRunHighGrayLevelEmphasis" 32.000000 ###
#     6.      "LongRunLowGrayLevelEmphasis" 27.000000 ###
#     7.     "ShortRunLowGrayLevelEmphasis" 25.000000 ##
#     8. "GrayLevelNonUniformityNormalized" 20.000000 ##
#     9.           "GrayLevelNonUniformity" 18.000000 ##
#    10.          "LowGrayLevelRunEmphasis" 17.000000 #
#    11.                      "RunVariance"  9.000000
#    12.           "RunLengthNonUniformity"  6.000000
#    13.                    "RunPercentage"  3.000000
#    14.                 "ShortRunEmphasis"  3.000000
#    15. "RunLengthNonUniformityNormalized"  2.000000
#    16.                  "LongRunEmphasis"  1.000000
#
# Variable Importance: SUM_SCORE:
#     1.     "LongRunHighGrayLevelEmphasis" 700.044726 ################
#     2.                       "RunEntropy" 57.937625 #
#     3.         "HighGrayLevelRunEmphasis" 26.712848
#     4.    "ShortRunHighGrayLevelEmphasis" 17.796606
#     5.      "LongRunLowGrayLevelEmphasis" 13.983524
#     6. "GrayLevelNonUniformityNormalized"  8.730103
#     7.           "GrayLevelNonUniformity"  7.998756
#     8.          "LowGrayLevelRunEmphasis"  5.439106
#     9.                "GrayLevelVariance"  5.422681
#    10.     "ShortRunLowGrayLevelEmphasis"  4.823596
#    11.           "RunLengthNonUniformity"  1.490163
#    12.                      "RunVariance"  1.115274
#    13.                 "ShortRunEmphasis"  0.908401
#    14.                    "RunPercentage"  0.546072
#    15.                  "LongRunEmphasis"  0.434261
#    16. "RunLengthNonUniformityNormalized"  0.282798
#
#
#
# Loss: BINOMIAL_LOG_LIKELIHOOD
# Validation loss value: 0.573169
# Number of trees per iteration: 1
# Node format: NOT_SET
# Number of trees: 24
# Total number of nodes: 924
#
# Number of nodes by tree:
# Count: 24 Average: 38.5 StdDev: 3.79693
# Min: 29 Max: 45 Ignored: 0
# ----------------------------------------------
# [ 29, 30) 1   4.17%   4.17% ##
# [ 30, 31) 0   0.00%   4.17%
# [ 31, 32) 1   4.17%   8.33% ##
# [ 32, 33) 0   0.00%   8.33%
# [ 33, 34) 1   4.17%  12.50% ##
# [ 34, 35) 0   0.00%  12.50%
# [ 35, 36) 2   8.33%  20.83% ###
# [ 36, 37) 0   0.00%  20.83%
# [ 37, 38) 4  16.67%  37.50% #######
# [ 38, 39) 0   0.00%  37.50%
# [ 39, 40) 6  25.00%  62.50% ##########
# [ 40, 41) 0   0.00%  62.50%
# [ 41, 42) 5  20.83%  83.33% ########
# [ 42, 43) 0   0.00%  83.33%
# [ 43, 44) 3  12.50%  95.83% #####
# [ 44, 45) 0   0.00%  95.83%
# [ 45, 45] 1   4.17% 100.00% ##
#
# Depth by leafs:
# Count: 474 Average: 4.5443 StdDev: 0.748514
# Min: 2 Max: 5 Ignored: 0
# ----------------------------------------------
# [ 2, 3)   4   0.84%   0.84%
# [ 3, 4)  62  13.08%  13.92% ##
# [ 4, 5)  80  16.88%  30.80% ##
# [ 5, 5] 328  69.20% 100.00% ##########
#
# Number of training obs by leaf:
# Count: 474 Average: 33.8734 StdDev: 71.0351
# Min: 5 Max: 397 Ignored: 0
# ----------------------------------------------
# [   5,  24) 353  74.47%  74.47% ##########
# [  24,  44)  39   8.23%  82.70% #
# [  44,  63)  33   6.96%  89.66% #
# [  63,  83)  13   2.74%  92.41%
# [  83, 103)   0   0.00%  92.41%
# [ 103, 122)   1   0.21%  92.62%
# [ 122, 142)   2   0.42%  93.04%
# [ 142, 162)   4   0.84%  93.88%
# [ 162, 181)   4   0.84%  94.73%
# [ 181, 201)   1   0.21%  94.94%
# [ 201, 221)   2   0.42%  95.36%
# [ 221, 240)   5   1.05%  96.41%
# [ 240, 260)   1   0.21%  96.62%
# [ 260, 280)   3   0.63%  97.26%
# [ 280, 299)   0   0.00%  97.26%
# [ 299, 319)   1   0.21%  97.47%
# [ 319, 339)   0   0.00%  97.47%
# [ 339, 358)   1   0.21%  97.68%
# [ 358, 378)   6   1.27%  98.95%
# [ 378, 397]   5   1.05% 100.00%
#
# Attribute in nodes:
# 	130 : LongRunHighGrayLevelEmphasis [NUMERICAL]
# 	83 : RunEntropy [NUMERICAL]
# 	37 : HighGrayLevelRunEmphasis [NUMERICAL]
# 	37 : GrayLevelVariance [NUMERICAL]
# 	32 : ShortRunHighGrayLevelEmphasis [NUMERICAL]
# 	27 : LongRunLowGrayLevelEmphasis [NUMERICAL]
# 	25 : ShortRunLowGrayLevelEmphasis [NUMERICAL]
# 	20 : GrayLevelNonUniformityNormalized [NUMERICAL]
# 	18 : GrayLevelNonUniformity [NUMERICAL]
# 	17 : LowGrayLevelRunEmphasis [NUMERICAL]
# 	9 : RunVariance [NUMERICAL]
# 	6 : RunLengthNonUniformity [NUMERICAL]
# 	3 : ShortRunEmphasis [NUMERICAL]
# 	3 : RunPercentage [NUMERICAL]
# 	2 : RunLengthNonUniformityNormalized [NUMERICAL]
# 	1 : LongRunEmphasis [NUMERICAL]
#
# Attribute in nodes with depth <= 0:
# 	24 : LongRunHighGrayLevelEmphasis [NUMERICAL]
#
# Attribute in nodes with depth <= 1:
# 	56 : LongRunHighGrayLevelEmphasis [NUMERICAL]
# 	6 : HighGrayLevelRunEmphasis [NUMERICAL]
# 	4 : ShortRunHighGrayLevelEmphasis [NUMERICAL]
# 	3 : LowGrayLevelRunEmphasis [NUMERICAL]
# 	3 : GrayLevelNonUniformityNormalized [NUMERICAL]
#
# Attribute in nodes with depth <= 2:
# 	72 : LongRunHighGrayLevelEmphasis [NUMERICAL]
# 	31 : RunEntropy [NUMERICAL]
# 	11 : HighGrayLevelRunEmphasis [NUMERICAL]
# 	8 : ShortRunLowGrayLevelEmphasis [NUMERICAL]
# 	8 : ShortRunHighGrayLevelEmphasis [NUMERICAL]
# 	8 : LongRunLowGrayLevelEmphasis [NUMERICAL]
# 	8 : GrayLevelNonUniformityNormalized [NUMERICAL]
# 	7 : GrayLevelVariance [NUMERICAL]
# 	5 : LowGrayLevelRunEmphasis [NUMERICAL]
# 	4 : GrayLevelNonUniformity [NUMERICAL]
# 	1 : RunVariance [NUMERICAL]
# 	1 : RunLengthNonUniformity [NUMERICAL]
#
# Attribute in nodes with depth <= 3:
# 	105 : LongRunHighGrayLevelEmphasis [NUMERICAL]
# 	51 : RunEntropy [NUMERICAL]
# 	23 : HighGrayLevelRunEmphasis [NUMERICAL]
# 	21 : ShortRunHighGrayLevelEmphasis [NUMERICAL]
# 	17 : ShortRunLowGrayLevelEmphasis [NUMERICAL]
# 	16 : LongRunLowGrayLevelEmphasis [NUMERICAL]
# 	12 : GrayLevelVariance [NUMERICAL]
# 	11 : LowGrayLevelRunEmphasis [NUMERICAL]
# 	11 : GrayLevelNonUniformityNormalized [NUMERICAL]
# 	10 : GrayLevelNonUniformity [NUMERICAL]
# 	3 : RunLengthNonUniformity [NUMERICAL]
# 	2 : ShortRunEmphasis [NUMERICAL]
# 	2 : RunVariance [NUMERICAL]
# 	1 : RunPercentage [NUMERICAL]
# 	1 : RunLengthNonUniformityNormalized [NUMERICAL]
#
# Attribute in nodes with depth <= 5:
# 	130 : LongRunHighGrayLevelEmphasis [NUMERICAL]
# 	83 : RunEntropy [NUMERICAL]
# 	37 : HighGrayLevelRunEmphasis [NUMERICAL]
# 	37 : GrayLevelVariance [NUMERICAL]
# 	32 : ShortRunHighGrayLevelEmphasis [NUMERICAL]
# 	27 : LongRunLowGrayLevelEmphasis [NUMERICAL]
# 	25 : ShortRunLowGrayLevelEmphasis [NUMERICAL]
# 	20 : GrayLevelNonUniformityNormalized [NUMERICAL]
# 	18 : GrayLevelNonUniformity [NUMERICAL]
# 	17 : LowGrayLevelRunEmphasis [NUMERICAL]
# 	9 : RunVariance [NUMERICAL]
# 	6 : RunLengthNonUniformity [NUMERICAL]
# 	3 : ShortRunEmphasis [NUMERICAL]
# 	3 : RunPercentage [NUMERICAL]
# 	2 : RunLengthNonUniformityNormalized [NUMERICAL]
# 	1 : LongRunEmphasis [NUMERICAL]
#
# Condition type in nodes:
# 	450 : HigherCondition
# Condition type in nodes with depth <= 0:
# 	24 : HigherCondition
# Condition type in nodes with depth <= 1:
# 	72 : HigherCondition
# Condition type in nodes with depth <= 2:
# 	164 : HigherCondition
# Condition type in nodes with depth <= 3:
# 	286 : HigherCondition
# Condition type in nodes with depth <= 5:
# 	450 : HigherCondition
#
# Training logs:
# Number of iteration to final model: 24
# 	Iter:1 train-loss:1.217963 valid-loss:1.232670  train-accuracy:0.964479 valid-accuracy:0.926261
# 	Iter:2 train-loss:1.079691 valid-loss:1.121718  train-accuracy:0.965351 valid-accuracy:0.876131
# 	Iter:3 train-loss:0.964229 valid-loss:1.028478  train-accuracy:0.965351 valid-accuracy:0.876131
# 	Iter:4 train-loss:0.865995 valid-loss:0.957810  train-accuracy:0.965351 valid-accuracy:0.876131
# 	Iter:5 train-loss:0.777534 valid-loss:0.880455  train-accuracy:0.974942 valid-accuracy:0.891871
# 	Iter:6 train-loss:0.699771 valid-loss:0.812948  train-accuracy:0.977557 valid-accuracy:0.891871
# 	Iter:16 train-loss:0.282662 valid-loss:0.584510  train-accuracy:0.991281 valid-accuracy:0.891871
# 	Iter:26 train-loss:0.131442 valid-loss:0.575495  train-accuracy:0.995641 valid-accuracy:0.891871
# 	Iter:36 train-loss:0.074989 valid-loss:0.606017  train-accuracy:0.995641 valid-accuracy:0.891871
# 	Iter:46 train-loss:0.049428 valid-loss:0.621218  train-accuracy:0.996512 valid-accuracy:0.891871

# %%
# Model features
model.make_inspector().features()
# Out:
# ["GrayLevelNonUniformity" (1; #0),
#  "GrayLevelNonUniformityNormalized" (1; #1),
#  "GrayLevelVariance" (1; #2),
#  "HighGrayLevelRunEmphasis" (1; #3),
#  "LongRunEmphasis" (1; #4),
#  "LongRunHighGrayLevelEmphasis" (1; #5),
#  "LongRunLowGrayLevelEmphasis" (1; #6),
#  "LowGrayLevelRunEmphasis" (1; #7),
#  "RunEntropy" (1; #8),
#  "RunLengthNonUniformity" (1; #9),
#  "RunLengthNonUniformityNormalized" (1; #10),
#  "RunPercentage" (1; #11),
#  "RunVariance" (1; #12),
#  "ShortRunEmphasis" (1; #13),
#  "ShortRunHighGrayLevelEmphasis" (1; #14),
#  "ShortRunLowGrayLevelEmphasis" (1; #15)]

# %%
# Feature importance
model.make_inspector().variable_importances()
# Out:
# {'INV_MEAN_MIN_DEPTH': [("LongRunHighGrayLevelEmphasis" (1; #5), 1.0),
#   ("RunEntropy" (1; #8), 0.23060085183842916),
#   ("HighGrayLevelRunEmphasis" (1; #3), 0.20108755618928056),
#   ("ShortRunHighGrayLevelEmphasis" (1; #14), 0.2002604203766906),
#   ("GrayLevelNonUniformityNormalized" (1; #1), 0.1955059857885556),
#   ("LongRunLowGrayLevelEmphasis" (1; #6), 0.19041509452506314),
#   ("LowGrayLevelRunEmphasis" (1; #7), 0.190329925756293),
#   ("GrayLevelVariance" (1; #2), 0.1898472452548309),
#   ("ShortRunLowGrayLevelEmphasis" (1; #15), 0.18920207727542154),
#   ("GrayLevelNonUniformity" (1; #0), 0.1867423174685363),
#   ("RunVariance" (1; #12), 0.18293696109323448),
#   ("RunLengthNonUniformity" (1; #9), 0.1821911620886383),
#   ("ShortRunEmphasis" (1; #13), 0.1817170533769835),
#   ("RunPercentage" (1; #11), 0.1814072651823128),
#   ("RunLengthNonUniformityNormalized" (1; #10), 0.18140132948262266),
#   ("LongRunEmphasis" (1; #4), 0.18088050465687278)],
#  'SUM_SCORE': [("LongRunHighGrayLevelEmphasis" (1; #5), 700.0447262970007),
#   ("RunEntropy" (1; #8), 57.937625301388266),
#   ("HighGrayLevelRunEmphasis" (1; #3), 26.712847864712398),
#   ("ShortRunHighGrayLevelEmphasis" (1; #14), 17.796606360670964),
#   ("LongRunLowGrayLevelEmphasis" (1; #6), 13.983524410808931),
#   ("GrayLevelNonUniformityNormalized" (1; #1), 8.730103033823342),
#   ("GrayLevelNonUniformity" (1; #0), 7.998755602210666),
#   ("LowGrayLevelRunEmphasis" (1; #7), 5.439106097599909),
#   ("GrayLevelVariance" (1; #2), 5.422681010230805),
#   ("ShortRunLowGrayLevelEmphasis" (1; #15), 4.82359622536524),
#   ("RunLengthNonUniformity" (1; #9), 1.490162543455864),
#   ("RunVariance" (1; #12), 1.1152737647845665),
#   ("ShortRunEmphasis" (1; #13), 0.9084010946879522),
#   ("RunPercentage" (1; #11), 0.5460723771112457),
#   ("LongRunEmphasis" (1; #4), 0.43426103795278875),
#   ("RunLengthNonUniformityNormalized" (1; #10), 0.2827980104771973)],
#  'NUM_AS_ROOT': [("LongRunHighGrayLevelEmphasis" (1; #5), 24.0)],
#  'NUM_NODES': [("LongRunHighGrayLevelEmphasis" (1; #5), 130.0),
#   ("RunEntropy" (1; #8), 83.0),
#   ("GrayLevelVariance" (1; #2), 37.0),
#   ("HighGrayLevelRunEmphasis" (1; #3), 37.0),
#   ("ShortRunHighGrayLevelEmphasis" (1; #14), 32.0),
#   ("LongRunLowGrayLevelEmphasis" (1; #6), 27.0),
#   ("ShortRunLowGrayLevelEmphasis" (1; #15), 25.0),
#   ("GrayLevelNonUniformityNormalized" (1; #1), 20.0),
#   ("GrayLevelNonUniformity" (1; #0), 18.0),
#   ("LowGrayLevelRunEmphasis" (1; #7), 17.0),
#   ("RunVariance" (1; #12), 9.0),
#   ("RunLengthNonUniformity" (1; #9), 6.0),
#   ("RunPercentage" (1; #11), 3.0),
#   ("ShortRunEmphasis" (1; #13), 3.0),
#   ("RunLengthNonUniformityNormalized" (1; #10), 2.0),
#   ("LongRunEmphasis" (1; #4), 1.0)]}

# %%
# Model self evaluation
model.make_inspector().evaluation()
# Out:
# Evaluation(num_examples=None, accuracy=0.8918706178665161, loss=0.573168933391571, rmse=None, ndcg=None, aucs=None, auuc=None, qini=None)

# %%
logs = model.make_inspector().training_logs()

plt.figure(figsize=(12, 4))
plt.subplot(1, 2, 1)
plt.plot([log.num_trees for log in logs], [log.evaluation.accuracy for log in logs])
plt.xlabel("Number of trees")
plt.ylabel("Accuracy (out-of-bag)")
plt.subplot(1, 2, 2)
plt.plot([log.num_trees for log in logs], [log.evaluation.loss for log in logs])
plt.xlabel("Number of trees")
plt.ylabel("Logloss (out-of-bag)")
plt.show()

# %% [markdown]
# Calculate the score of our hold-out validation dataset

# %%
predictions = model.predict(val_ds)
y_true      = validation_data["label"]

from sklearn.metrics import roc_auc_score
ROC_AUC = roc_auc_score(y_true, predictions)
print("The ROC AUC score is %.5f" % ROC_AUC )
# Out:
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 64ms/step
# The ROC AUC score is 0.97214

# %%
# Compute binary classification metrics with sklearn
import numpy as np
from sklearn.metrics import (
    accuracy_score,
    precision_score,
    recall_score,
    f1_score,
    roc_auc_score,
    average_precision_score,
    confusion_matrix,
    classification_report,
    matthews_corrcoef,
    log_loss,
    brier_score_loss,
)

# Get predictions (probabilities or class labels)
preds = model.predict(test_ds)
# If model outputs probabilities, convert to labels by threshold 0.5
if preds.ndim == 2:
    # For TFDF classification, preds may be class probabilities with shape (N, 2)
    if preds.shape[1] == 2:
        pos_probs = preds[:, 1]
    else:
        # If single-probability column (positive class)
        pos_probs = preds[:, -1]
    y_pred = (pos_probs >= 0.5).astype(int)
else:
    # Already class labels
    y_pred = preds.astype(int)
    pos_probs = None

# Ground truth labels (must be 0/1 integers)
y_true = test_data["label"].astype(int).to_numpy()

# Core metrics
metrics = {}
metrics["accuracy"] = accuracy_score(y_true, y_pred)
metrics["precision"] = precision_score(y_true, y_pred, zero_division=0)
metrics["recall"] = recall_score(y_true, y_pred, zero_division=0)
metrics["f1"] = f1_score(y_true, y_pred, zero_division=0)
metrics["mcc"] = matthews_corrcoef(y_true, y_pred)

# Probabilistic metrics (only if we have probabilities)
if pos_probs is not None:
    metrics["roc_auc"] = roc_auc_score(y_true, pos_probs)
    metrics["pr_auc"] = average_precision_score(y_true, pos_probs)
    metrics["log_loss"] = log_loss(y_true, pos_probs, labels=[0,1])
    metrics["brier_score"] = brier_score_loss(y_true, pos_probs)

# Confusion matrix and detailed report
cm = confusion_matrix(y_true, y_pred, labels=[0,1])
report = classification_report(y_true, y_pred, digits=4)

print("Sklearn binary metrics:")
for k, v in metrics.items():
    print(f"{k}: {v:.4f}")
print("\nConfusion matrix:\n", cm)
print("\nClassification report:\n", report)
# Out:
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 84ms/step
# Sklearn binary metrics:
# accuracy: 0.9717
# precision: 0.9200
# recall: 0.8519
# f1: 0.8846
# mcc: 0.8693
# roc_auc: 0.9772
# pr_auc: 0.9276
# log_loss: 0.1248
# brier_score: 0.0273
#
# Confusion matrix:
#  [[183   2]
#  [  4  23]]
#
# Classification report:
#                precision    recall  f1-score   support
#
#            0     0.9786    0.9892    0.9839       185
#            1     0.9200    0.8519    0.8846        27
#
#     accuracy                         0.9717       212
#    macro avg     0.9493    0.9205    0.9342       212
# weighted avg     0.9711    0.9717    0.9712       212
