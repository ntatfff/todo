# %%
# Import packages and modules
import numpy  as np
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow_decision_forests as tfdf

from sklearn.model_selection import train_test_split
# Out:
# 2026-08-13 04:16:59.698063: I tensorflow/core/util/port.cc:113] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2026-08-13 04:17:00.087943: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2026-08-13 04:17:05.097280: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
# Check the version of TensorFlow Decision Forests
print("Found TensorFlow Decision Forests v" + tfdf.__version__)
# Out:
# Found TensorFlow Decision Forests v1.9.1

# %%
datasetPath = 'dataset/firstorder/kernel5/dataset.csv'

# %%
# Parameters
datasetPath = "dataset/glszm/kernel5/1.dataset.csv"

# %%
# train/validation/test = 70/10/20
dataset = pd.read_csv(datasetPath)

train_data, temp_data = train_test_split(dataset, test_size=0.3, random_state=42)
validation_data, test_data = train_test_split(temp_data, test_size=2/3, random_state=42)

# %%
from sklearn.utils.class_weight import compute_class_weight

# tinh class weight tren tap train
classes = np.array([0, 1])
weights = compute_class_weight(class_weight="balanced", classes=classes, y=train_data["label"])
class_weight = {0: weights[0], 1: weights[1]}

# gan sample_weight cho tung dong
train_data["sample_weight"] = train_data["label"].map(class_weight)
validation_data["sample_weight"] = validation_data["label"].map(class_weight)
test_data["sample_weight"] = test_data["label"].map(class_weight)

# Convert the dataset into a TensorFlow dataset.
train_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    train_data, label="label", weight="sample_weight"
)         
val_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    validation_data, label="label", weight="sample_weight"
)
test_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    test_data, label="label", weight="sample_weight"
)
# Out:
# 2026-08-13 04:17:18.730962: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:984] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2026-08-13 04:17:18.733379: W tensorflow/core/common_runtime/gpu/gpu_device.cc:2251] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...

# %%
import keras

# %%
# %%time

# Train a Gradient Boosted Trees model.
model = tfdf.keras.GradientBoostedTreesModel()

# Add evaluation metrics
model.compile(
    metrics=["accuracy"]
)
model.fit(x=train_ds)

# # Train a Gradient Boosted Trees model.
# model = tfdf.keras.GradientBoostedTreesModel(num_trees=1500)
# model.fit(train_ds)
# Out:
# Use /tmp/tmpoyrsubsu as temporary training directory
# Reading training dataset...
# [WARNING 26-08-13 04:17:18.8792 UTC gradient_boosted_trees.cc:1840] "goss_alpha" set but "sampling_method" not equal to "GOSS".
# [WARNING 26-08-13 04:17:18.8794 UTC gradient_boosted_trees.cc:1851] "goss_beta" set but "sampling_method" not equal to "GOSS".
# [WARNING 26-08-13 04:17:18.8794 UTC gradient_boosted_trees.cc:1865] "selective_gradient_boosting_ratio" set but "sampling_method" not equal to "SELGB".
# Training dataset read in 0:00:02.586703. Found 737 examples.
# Training model...
# Model trained in 0:00:00.263569
# Compiling model...
# [INFO 26-08-13 04:17:21.7587 UTC kernel.cc:1233] Loading model from path /tmp/tmpoyrsubsu/model/ with prefix e9866023b65c41d7
# [INFO 26-08-13 04:17:21.7611 UTC quick_scorer_extended.cc:911] The binary was compiled without AVX2 support, but your CPU supports it. Enable it for faster model inference.
# [INFO 26-08-13 04:17:21.7612 UTC abstract_model.cc:1362] Engine "GradientBoostedTreesQuickScorerExtended" built
# [INFO 26-08-13 04:17:21.7612 UTC kernel.cc:1061] Use fast generic engine
# Model compiled.
# CPU times: user 5.65 s, sys: 414 ms, total: 6.06 s
# Wall time: 6.14 s

# %%
# Evaluate the model
evaluate = model.evaluate(val_ds, return_dict=True)
print()

for name, value in evaluate.items():
    print(f"{name}: {value:.4f}")
# Out:
# WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 1/1 [==============================] - ETA: 0s - loss: 0.0000e+00 - accuracy: 0.8952
# 1/1 [==============================] - 3s 3s/step - loss: 0.0000e+00 - accuracy: 0.8952
# loss: 0.0000
# accuracy: 0.8952

# %%
# Model Summary
model.summary()
# Out:
# Model: "gradient_boosted_trees_model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
# =================================================================
# Total params: 1 (1.00 Byte)
# Trainable params: 0 (0.00 Byte)
# Non-trainable params: 1 (1.00 Byte)
# _________________________________________________________________
# Type: "GRADIENT_BOOSTED_TREES"
# Task: CLASSIFICATION
# Label: "__LABEL"
#
# Input Features (16):
# 	GrayLevelNonUniformity
# 	GrayLevelNonUniformityNormalized
# 	GrayLevelVariance
# 	HighGrayLevelZoneEmphasis
# 	LargeAreaEmphasis
# 	LargeAreaHighGrayLevelEmphasis
# 	LargeAreaLowGrayLevelEmphasis
# 	LowGrayLevelZoneEmphasis
# 	SizeZoneNonUniformity
# 	SizeZoneNonUniformityNormalized
# 	SmallAreaEmphasis
# 	SmallAreaHighGrayLevelEmphasis
# 	SmallAreaLowGrayLevelEmphasis
# 	ZoneEntropy
# 	ZonePercentage
# 	ZoneVariance
#
# Trained with weights
#
# Variable Importance: INV_MEAN_MIN_DEPTH:
#     1.        "HighGrayLevelZoneEmphasis"  1.000000 ################
#     2.    "SmallAreaLowGrayLevelEmphasis"  0.261895 #
#     3.   "LargeAreaHighGrayLevelEmphasis"  0.257178 #
#     4.           "GrayLevelNonUniformity"  0.215256
#     5.                "GrayLevelVariance"  0.210907
#     6. "GrayLevelNonUniformityNormalized"  0.199497
#     7.    "LargeAreaLowGrayLevelEmphasis"  0.192283
#     8.         "LowGrayLevelZoneEmphasis"  0.190771
#     9.   "SmallAreaHighGrayLevelEmphasis"  0.184481
#    10.                      "ZoneEntropy"  0.183869
#    11.                     "ZoneVariance"  0.180424
#    12.  "SizeZoneNonUniformityNormalized"  0.180296
#    13.            "SizeZoneNonUniformity"  0.179789
#    14.                "SmallAreaEmphasis"  0.179599
#    15.                "LargeAreaEmphasis"  0.179379
#    16.                   "ZonePercentage"  0.178860
#
# Variable Importance: NUM_AS_ROOT:
#     1. "HighGrayLevelZoneEmphasis" 28.000000
#
# Variable Importance: NUM_NODES:
#     1.    "SmallAreaLowGrayLevelEmphasis" 85.000000 ################
#     2.   "LargeAreaHighGrayLevelEmphasis" 80.000000 ##############
#     3.           "GrayLevelNonUniformity" 70.000000 ############
#     4.    "LargeAreaLowGrayLevelEmphasis" 56.000000 #########
#     5.        "HighGrayLevelZoneEmphasis" 52.000000 ########
#     6.                "GrayLevelVariance" 50.000000 ########
#     7.         "LowGrayLevelZoneEmphasis" 41.000000 ######
#     8. "GrayLevelNonUniformityNormalized" 37.000000 #####
#     9.   "SmallAreaHighGrayLevelEmphasis" 27.000000 ###
#    10.                      "ZoneEntropy" 27.000000 ###
#    11.            "SizeZoneNonUniformity" 21.000000 ##
#    12.                "LargeAreaEmphasis" 13.000000
#    13.                "SmallAreaEmphasis" 13.000000
#    14.                     "ZoneVariance" 13.000000
#    15.  "SizeZoneNonUniformityNormalized" 12.000000
#    16.                   "ZonePercentage" 10.000000
#
# Variable Importance: SUM_SCORE:
#     1.        "HighGrayLevelZoneEmphasis" 556.775033 ################
#     2.           "GrayLevelNonUniformity" 78.909303 ##
#     3.   "LargeAreaHighGrayLevelEmphasis" 56.053850 #
#     4.    "LargeAreaLowGrayLevelEmphasis" 46.275410 #
#     5.    "SmallAreaLowGrayLevelEmphasis" 39.261307 #
#     6.                "GrayLevelVariance" 24.901973
#     7. "GrayLevelNonUniformityNormalized" 16.780995
#     8.   "SmallAreaHighGrayLevelEmphasis" 12.368848
#     9.                      "ZoneEntropy" 11.880048
#    10.         "LowGrayLevelZoneEmphasis"  7.759062
#    11.                     "ZoneVariance"  7.537441
#    12.                "LargeAreaEmphasis"  5.382635
#    13.                "SmallAreaEmphasis"  3.638305
#    14.            "SizeZoneNonUniformity"  1.902716
#    15.                   "ZonePercentage"  0.501529
#    16.  "SizeZoneNonUniformityNormalized"  0.193994
#
#
#
# Loss: BINOMIAL_LOG_LIKELIHOOD
# Validation loss value: 0.414854
# Number of trees per iteration: 1
# Node format: NOT_SET
# Number of trees: 28
# Total number of nodes: 1242
#
# Number of nodes by tree:
# Count: 28 Average: 44.3571 StdDev: 4.56864
# Min: 37 Max: 55 Ignored: 0
# ----------------------------------------------
# [ 37, 38) 1   3.57%   3.57% #
# [ 38, 39) 0   0.00%   3.57%
# [ 39, 40) 3  10.71%  14.29% ####
# [ 40, 41) 0   0.00%  14.29%
# [ 41, 42) 8  28.57%  42.86% ##########
# [ 42, 43) 0   0.00%  42.86%
# [ 43, 44) 3  10.71%  53.57% ####
# [ 44, 45) 0   0.00%  53.57%
# [ 45, 46) 3  10.71%  64.29% ####
# [ 46, 47) 0   0.00%  64.29%
# [ 47, 48) 4  14.29%  78.57% #####
# [ 48, 49) 0   0.00%  78.57%
# [ 49, 50) 2   7.14%  85.71% ###
# [ 50, 51) 0   0.00%  85.71%
# [ 51, 52) 2   7.14%  92.86% ###
# [ 52, 53) 0   0.00%  92.86%
# [ 53, 54) 1   3.57%  96.43% #
# [ 54, 55) 0   0.00%  96.43%
# [ 55, 55] 1   3.57% 100.00% #
#
# Depth by leafs:
# Count: 635 Average: 4.65354 StdDev: 0.59364
# Min: 2 Max: 5 Ignored: 0
# ----------------------------------------------
# [ 2, 3)   1   0.16%   0.16%
# [ 3, 4)  37   5.83%   5.98% #
# [ 4, 5) 143  22.52%  28.50% ###
# [ 5, 5] 454  71.50% 100.00% ##########
#
# Number of training obs by leaf:
# Count: 635 Average: 29.4992 StdDev: 78.794
# Min: 5 Max: 443 Ignored: 0
# ----------------------------------------------
# [   5,  26) 525  82.68%  82.68% ##########
# [  26,  48)  61   9.61%  92.28% #
# [  48,  70)  16   2.52%  94.80%
# [  70,  92)   2   0.31%  95.12%
# [  92, 114)   2   0.31%  95.43%
# [ 114, 136)   0   0.00%  95.43%
# [ 136, 158)   0   0.00%  95.43%
# [ 158, 180)   1   0.16%  95.59%
# [ 180, 202)   0   0.00%  95.59%
# [ 202, 224)   0   0.00%  95.59%
# [ 224, 246)   0   0.00%  95.59%
# [ 246, 268)   1   0.16%  95.75%
# [ 268, 290)   0   0.00%  95.75%
# [ 290, 312)   0   0.00%  95.75%
# [ 312, 334)   1   0.16%  95.91%
# [ 334, 356)   1   0.16%  96.06%
# [ 356, 378)   7   1.10%  97.17%
# [ 378, 400)   7   1.10%  98.27%
# [ 400, 422)   7   1.10%  99.37%
# [ 422, 443]   4   0.63% 100.00%
#
# Attribute in nodes:
# 	85 : SmallAreaLowGrayLevelEmphasis [NUMERICAL]
# 	80 : LargeAreaHighGrayLevelEmphasis [NUMERICAL]
# 	70 : GrayLevelNonUniformity [NUMERICAL]
# 	56 : LargeAreaLowGrayLevelEmphasis [NUMERICAL]
# 	52 : HighGrayLevelZoneEmphasis [NUMERICAL]
# 	50 : GrayLevelVariance [NUMERICAL]
# 	41 : LowGrayLevelZoneEmphasis [NUMERICAL]
# 	37 : GrayLevelNonUniformityNormalized [NUMERICAL]
# 	27 : ZoneEntropy [NUMERICAL]
# 	27 : SmallAreaHighGrayLevelEmphasis [NUMERICAL]
# 	21 : SizeZoneNonUniformity [NUMERICAL]
# 	13 : ZoneVariance [NUMERICAL]
# 	13 : SmallAreaEmphasis [NUMERICAL]
# 	13 : LargeAreaEmphasis [NUMERICAL]
# 	12 : SizeZoneNonUniformityNormalized [NUMERICAL]
# 	10 : ZonePercentage [NUMERICAL]
#
# Attribute in nodes with depth <= 0:
# 	28 : HighGrayLevelZoneEmphasis [NUMERICAL]
#
# Attribute in nodes with depth <= 1:
# 	28 : HighGrayLevelZoneEmphasis [NUMERICAL]
# 	20 : SmallAreaLowGrayLevelEmphasis [NUMERICAL]
# 	18 : LargeAreaHighGrayLevelEmphasis [NUMERICAL]
# 	8 : GrayLevelVariance [NUMERICAL]
# 	5 : GrayLevelNonUniformityNormalized [NUMERICAL]
# 	5 : GrayLevelNonUniformity [NUMERICAL]
#
# Attribute in nodes with depth <= 2:
# 	40 : SmallAreaLowGrayLevelEmphasis [NUMERICAL]
# 	34 : LargeAreaHighGrayLevelEmphasis [NUMERICAL]
# 	31 : HighGrayLevelZoneEmphasis [NUMERICAL]
# 	26 : GrayLevelNonUniformity [NUMERICAL]
# 	20 : GrayLevelVariance [NUMERICAL]
# 	12 : LowGrayLevelZoneEmphasis [NUMERICAL]
# 	11 : GrayLevelNonUniformityNormalized [NUMERICAL]
# 	5 : SmallAreaHighGrayLevelEmphasis [NUMERICAL]
# 	5 : LargeAreaLowGrayLevelEmphasis [NUMERICAL]
# 	4 : ZoneVariance [NUMERICAL]
# 	2 : ZoneEntropy [NUMERICAL]
# 	2 : SizeZoneNonUniformityNormalized [NUMERICAL]
# 	1 : ZonePercentage [NUMERICAL]
# 	1 : SmallAreaEmphasis [NUMERICAL]
# 	1 : LargeAreaEmphasis [NUMERICAL]
#
# Attribute in nodes with depth <= 3:
# 	66 : SmallAreaLowGrayLevelEmphasis [NUMERICAL]
# 	59 : LargeAreaHighGrayLevelEmphasis [NUMERICAL]
# 	44 : HighGrayLevelZoneEmphasis [NUMERICAL]
# 	44 : GrayLevelNonUniformity [NUMERICAL]
# 	36 : GrayLevelVariance [NUMERICAL]
# 	29 : LargeAreaLowGrayLevelEmphasis [NUMERICAL]
# 	27 : LowGrayLevelZoneEmphasis [NUMERICAL]
# 	16 : GrayLevelNonUniformityNormalized [NUMERICAL]
# 	13 : SmallAreaHighGrayLevelEmphasis [NUMERICAL]
# 	12 : ZoneEntropy [NUMERICAL]
# 	9 : ZoneVariance [NUMERICAL]
# 	8 : LargeAreaEmphasis [NUMERICAL]
# 	7 : SizeZoneNonUniformityNormalized [NUMERICAL]
# 	5 : SmallAreaEmphasis [NUMERICAL]
# 	3 : SizeZoneNonUniformity [NUMERICAL]
# 	2 : ZonePercentage [NUMERICAL]
#
# Attribute in nodes with depth <= 5:
# 	85 : SmallAreaLowGrayLevelEmphasis [NUMERICAL]
# 	80 : LargeAreaHighGrayLevelEmphasis [NUMERICAL]
# 	70 : GrayLevelNonUniformity [NUMERICAL]
# 	56 : LargeAreaLowGrayLevelEmphasis [NUMERICAL]
# 	52 : HighGrayLevelZoneEmphasis [NUMERICAL]
# 	50 : GrayLevelVariance [NUMERICAL]
# 	41 : LowGrayLevelZoneEmphasis [NUMERICAL]
# 	37 : GrayLevelNonUniformityNormalized [NUMERICAL]
# 	27 : ZoneEntropy [NUMERICAL]
# 	27 : SmallAreaHighGrayLevelEmphasis [NUMERICAL]
# 	21 : SizeZoneNonUniformity [NUMERICAL]
# 	13 : ZoneVariance [NUMERICAL]
# 	13 : SmallAreaEmphasis [NUMERICAL]
# 	13 : LargeAreaEmphasis [NUMERICAL]
# 	12 : SizeZoneNonUniformityNormalized [NUMERICAL]
# 	10 : ZonePercentage [NUMERICAL]
#
# Condition type in nodes:
# 	607 : HigherCondition
# Condition type in nodes with depth <= 0:
# 	28 : HigherCondition
# Condition type in nodes with depth <= 1:
# 	84 : HigherCondition
# Condition type in nodes with depth <= 2:
# 	195 : HigherCondition
# Condition type in nodes with depth <= 3:
# 	380 : HigherCondition
# Condition type in nodes with depth <= 5:
# 	607 : HigherCondition
#
# Training logs:
# Number of iteration to final model: 28
# 	Iter:1 train-loss:1.215295 valid-loss:1.241196  train-accuracy:0.967690 valid-accuracy:0.893901
# 	Iter:2 train-loss:1.074740 valid-loss:1.125085  train-accuracy:0.975549 valid-accuracy:0.911942
# 	Iter:3 train-loss:0.957325 valid-loss:1.034166  train-accuracy:0.974676 valid-accuracy:0.902921
# 	Iter:4 train-loss:0.858122 valid-loss:0.952383  train-accuracy:0.976422 valid-accuracy:0.911942
# 	Iter:5 train-loss:0.773174 valid-loss:0.889235  train-accuracy:0.976422 valid-accuracy:0.911942
# 	Iter:6 train-loss:0.699207 valid-loss:0.832420  train-accuracy:0.978169 valid-accuracy:0.911942
# 	Iter:16 train-loss:0.289590 valid-loss:0.505379  train-accuracy:0.985155 valid-accuracy:0.920963
# 	Iter:26 train-loss:0.142345 valid-loss:0.420425  train-accuracy:0.990394 valid-accuracy:0.920963
# 	Iter:36 train-loss:0.081718 valid-loss:0.448951  train-accuracy:0.994761 valid-accuracy:0.868989
# 	Iter:46 train-loss:0.050391 valid-loss:0.508331  train-accuracy:0.998254 valid-accuracy:0.817016
# 	Iter:56 train-loss:0.032043 valid-loss:0.652015  train-accuracy:0.999127 valid-accuracy:0.826037

# %%
# Model features
model.make_inspector().features()
# Out:
# ["GrayLevelNonUniformity" (1; #0),
#  "GrayLevelNonUniformityNormalized" (1; #1),
#  "GrayLevelVariance" (1; #2),
#  "HighGrayLevelZoneEmphasis" (1; #3),
#  "LargeAreaEmphasis" (1; #4),
#  "LargeAreaHighGrayLevelEmphasis" (1; #5),
#  "LargeAreaLowGrayLevelEmphasis" (1; #6),
#  "LowGrayLevelZoneEmphasis" (1; #7),
#  "SizeZoneNonUniformity" (1; #8),
#  "SizeZoneNonUniformityNormalized" (1; #9),
#  "SmallAreaEmphasis" (1; #10),
#  "SmallAreaHighGrayLevelEmphasis" (1; #11),
#  "SmallAreaLowGrayLevelEmphasis" (1; #12),
#  "ZoneEntropy" (1; #13),
#  "ZonePercentage" (1; #14),
#  "ZoneVariance" (1; #15)]

# %%
# Feature importance
model.make_inspector().variable_importances()
# Out:
# {'INV_MEAN_MIN_DEPTH': [("HighGrayLevelZoneEmphasis" (1; #3), 1.0),
#   ("SmallAreaLowGrayLevelEmphasis" (1; #12), 0.26189520948193384),
#   ("LargeAreaHighGrayLevelEmphasis" (1; #5), 0.2571784786014372),
#   ("GrayLevelNonUniformity" (1; #0), 0.2152563989865811),
#   ("GrayLevelVariance" (1; #2), 0.21090707989910815),
#   ("GrayLevelNonUniformityNormalized" (1; #1), 0.19949729175388434),
#   ("LargeAreaLowGrayLevelEmphasis" (1; #6), 0.1922831508163962),
#   ("LowGrayLevelZoneEmphasis" (1; #7), 0.19077060439456198),
#   ("SmallAreaHighGrayLevelEmphasis" (1; #11), 0.18448089303008147),
#   ("ZoneEntropy" (1; #13), 0.18386943242388845),
#   ("ZoneVariance" (1; #15), 0.18042393806167717),
#   ("SizeZoneNonUniformityNormalized" (1; #9), 0.18029599911820546),
#   ("SizeZoneNonUniformity" (1; #8), 0.1797889761872233),
#   ("SmallAreaEmphasis" (1; #10), 0.17959853481564153),
#   ("LargeAreaEmphasis" (1; #4), 0.17937922662480907),
#   ("ZonePercentage" (1; #14), 0.17886048224579146)],
#  'SUM_SCORE': [("HighGrayLevelZoneEmphasis" (1; #3), 556.7750333877823),
#   ("GrayLevelNonUniformity" (1; #0), 78.90930320063535),
#   ("LargeAreaHighGrayLevelEmphasis" (1; #5), 56.05385007059791),
#   ("LargeAreaLowGrayLevelEmphasis" (1; #6), 46.27540992951902),
#   ("SmallAreaLowGrayLevelEmphasis" (1; #12), 39.261307017187335),
#   ("GrayLevelVariance" (1; #2), 24.901973097028655),
#   ("GrayLevelNonUniformityNormalized" (1; #1), 16.780995200965393),
#   ("SmallAreaHighGrayLevelEmphasis" (1; #11), 12.36884839875175),
#   ("ZoneEntropy" (1; #13), 11.880047924801188),
#   ("LowGrayLevelZoneEmphasis" (1; #7), 7.759062243681613),
#   ("ZoneVariance" (1; #15), 7.537441357175406),
#   ("LargeAreaEmphasis" (1; #4), 5.382634754616222),
#   ("SmallAreaEmphasis" (1; #10), 3.638304867862022),
#   ("SizeZoneNonUniformity" (1; #8), 1.902715526482169),
#   ("ZonePercentage" (1; #14), 0.5015287855807121),
#   ("SizeZoneNonUniformityNormalized" (1; #9), 0.1939942978218705)],
#  'NUM_AS_ROOT': [("HighGrayLevelZoneEmphasis" (1; #3), 28.0)],
#  'NUM_NODES': [("SmallAreaLowGrayLevelEmphasis" (1; #12), 85.0),
#   ("LargeAreaHighGrayLevelEmphasis" (1; #5), 80.0),
#   ("GrayLevelNonUniformity" (1; #0), 70.0),
#   ("LargeAreaLowGrayLevelEmphasis" (1; #6), 56.0),
#   ("HighGrayLevelZoneEmphasis" (1; #3), 52.0),
#   ("GrayLevelVariance" (1; #2), 50.0),
#   ("LowGrayLevelZoneEmphasis" (1; #7), 41.0),
#   ("GrayLevelNonUniformityNormalized" (1; #1), 37.0),
#   ("SmallAreaHighGrayLevelEmphasis" (1; #11), 27.0),
#   ("ZoneEntropy" (1; #13), 27.0),
#   ("SizeZoneNonUniformity" (1; #8), 21.0),
#   ("LargeAreaEmphasis" (1; #4), 13.0),
#   ("SmallAreaEmphasis" (1; #10), 13.0),
#   ("ZoneVariance" (1; #15), 13.0),
#   ("SizeZoneNonUniformityNormalized" (1; #9), 12.0),
#   ("ZonePercentage" (1; #14), 10.0)]}

# %%
# Model self evaluation
model.make_inspector().evaluation()
# Out:
# Evaluation(num_examples=None, accuracy=0.9209633469581604, loss=0.4148538112640381, rmse=None, ndcg=None, aucs=None, auuc=None, qini=None)

# %%
logs = model.make_inspector().training_logs()

plt.figure(figsize=(12, 4))
plt.subplot(1, 2, 1)
plt.plot([log.num_trees for log in logs], [log.evaluation.accuracy for log in logs])
plt.xlabel("Number of trees")
plt.ylabel("Accuracy (out-of-bag)")
plt.subplot(1, 2, 2)
plt.plot([log.num_trees for log in logs], [log.evaluation.loss for log in logs])
plt.xlabel("Number of trees")
plt.ylabel("Logloss (out-of-bag)")
plt.show()

# %% [markdown]
# Calculate the score of our hold-out validation dataset

# %%
predictions = model.predict(val_ds)
y_true      = validation_data["label"]

from sklearn.metrics import roc_auc_score
ROC_AUC = roc_auc_score(y_true, predictions)
print("The ROC AUC score is %.5f" % ROC_AUC )
# Out:
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 57ms/step
# The ROC AUC score is 0.69023

# %%
# Compute binary classification metrics with sklearn
import numpy as np
from sklearn.metrics import (
    accuracy_score,
    precision_score,
    recall_score,
    f1_score,
    roc_auc_score,
    average_precision_score,
    confusion_matrix,
    classification_report,
    matthews_corrcoef,
    log_loss,
    brier_score_loss,
)

# Get predictions (probabilities or class labels)
preds = model.predict(test_ds)
# If model outputs probabilities, convert to labels by threshold 0.5
if preds.ndim == 2:
    # For TFDF classification, preds may be class probabilities with shape (N, 2)
    if preds.shape[1] == 2:
        pos_probs = preds[:, 1]
    else:
        # If single-probability column (positive class)
        pos_probs = preds[:, -1]
    y_pred = (pos_probs >= 0.5).astype(int)
else:
    # Already class labels
    y_pred = preds.astype(int)
    pos_probs = None

# Ground truth labels (must be 0/1 integers)
y_true = test_data["label"].astype(int).to_numpy()

# Core metrics
metrics = {}
metrics["accuracy"] = accuracy_score(y_true, y_pred)
metrics["precision"] = precision_score(y_true, y_pred, zero_division=0)
metrics["recall"] = recall_score(y_true, y_pred, zero_division=0)
metrics["f1"] = f1_score(y_true, y_pred, zero_division=0)
metrics["mcc"] = matthews_corrcoef(y_true, y_pred)

# Probabilistic metrics (only if we have probabilities)
if pos_probs is not None:
    metrics["roc_auc"] = roc_auc_score(y_true, pos_probs)
    metrics["pr_auc"] = average_precision_score(y_true, pos_probs)
    metrics["log_loss"] = log_loss(y_true, pos_probs, labels=[0,1])
    metrics["brier_score"] = brier_score_loss(y_true, pos_probs)

# Confusion matrix and detailed report
cm = confusion_matrix(y_true, y_pred, labels=[0,1])
report = classification_report(y_true, y_pred, digits=4)

print("Sklearn binary metrics:")
for k, v in metrics.items():
    print(f"{k}: {v:.4f}")
print("\nConfusion matrix:\n", cm)
print("\nClassification report:\n", report)
# Out:
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 66ms/step
# Sklearn binary metrics:
# accuracy: 0.9292
# precision: 0.7083
# recall: 0.6800
# f1: 0.6939
# mcc: 0.6541
# roc_auc: 0.9255
# pr_auc: 0.8069
# log_loss: 0.1910
# brier_score: 0.0536
#
# Confusion matrix:
#  [[180   7]
#  [  8  17]]
#
# Classification report:
#                precision    recall  f1-score   support
#
#            0     0.9574    0.9626    0.9600       187
#            1     0.7083    0.6800    0.6939        25
#
#     accuracy                         0.9292       212
#    macro avg     0.8329    0.8213    0.8269       212
# weighted avg     0.9281    0.9292    0.9286       212
