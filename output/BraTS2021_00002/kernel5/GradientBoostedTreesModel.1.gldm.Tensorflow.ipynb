# %%
# Import packages and modules
import numpy  as np
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow_decision_forests as tfdf

from sklearn.model_selection import train_test_split
# Out:
# 2026-08-13 04:15:44.434284: I tensorflow/core/util/port.cc:113] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2026-08-13 04:15:44.804732: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2026-08-13 04:15:49.701969: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
# Check the version of TensorFlow Decision Forests
print("Found TensorFlow Decision Forests v" + tfdf.__version__)
# Out:
# Found TensorFlow Decision Forests v1.9.1

# %%
datasetPath = 'dataset/firstorder/kernel5/dataset.csv'

# %%
# Parameters
datasetPath = "dataset/gldm/kernel5/1.dataset.csv"

# %%
# train/validation/test = 70/10/20
dataset = pd.read_csv(datasetPath)

train_data, temp_data = train_test_split(dataset, test_size=0.3, random_state=42)
validation_data, test_data = train_test_split(temp_data, test_size=2/3, random_state=42)

# %%
from sklearn.utils.class_weight import compute_class_weight

# tinh class weight tren tap train
classes = np.array([0, 1])
weights = compute_class_weight(class_weight="balanced", classes=classes, y=train_data["label"])
class_weight = {0: weights[0], 1: weights[1]}

# gan sample_weight cho tung dong
train_data["sample_weight"] = train_data["label"].map(class_weight)
validation_data["sample_weight"] = validation_data["label"].map(class_weight)
test_data["sample_weight"] = test_data["label"].map(class_weight)

# Convert the dataset into a TensorFlow dataset.
train_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    train_data, label="label", weight="sample_weight"
)         
val_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    validation_data, label="label", weight="sample_weight"
)
test_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    test_data, label="label", weight="sample_weight"
)
# Out:
# 2026-08-13 04:16:03.726858: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:984] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2026-08-13 04:16:03.728484: W tensorflow/core/common_runtime/gpu/gpu_device.cc:2251] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...

# %%
import keras

# %%
# %%time

# Train a Gradient Boosted Trees model.
model = tfdf.keras.GradientBoostedTreesModel()

# Add evaluation metrics
model.compile(
    metrics=["accuracy"]
)
model.fit(x=train_ds)

# # Train a Gradient Boosted Trees model.
# model = tfdf.keras.GradientBoostedTreesModel(num_trees=1500)
# model.fit(train_ds)
# Out:
# Use /tmp/tmp_e0d0vo2 as temporary training directory
# Reading training dataset...
# [WARNING 26-08-13 04:16:04.4051 UTC gradient_boosted_trees.cc:1840] "goss_alpha" set but "sampling_method" not equal to "GOSS".
# [WARNING 26-08-13 04:16:04.4054 UTC gradient_boosted_trees.cc:1851] "goss_beta" set but "sampling_method" not equal to "GOSS".
# [WARNING 26-08-13 04:16:04.4054 UTC gradient_boosted_trees.cc:1865] "selective_gradient_boosting_ratio" set but "sampling_method" not equal to "SELGB".
# Training dataset read in 0:00:02.552026. Found 737 examples.
# Training model...
# Model trained in 0:00:00.197443
# Compiling model...
# [INFO 26-08-13 04:16:07.1858 UTC kernel.cc:1233] Loading model from path /tmp/tmp_e0d0vo2/model/ with prefix f88b9f345a334a16
# [INFO 26-08-13 04:16:07.1877 UTC quick_scorer_extended.cc:911] The binary was compiled without AVX2 support, but your CPU supports it. Enable it for faster model inference.
# [INFO 26-08-13 04:16:07.1878 UTC abstract_model.cc:1362] Engine "GradientBoostedTreesQuickScorerExtended" built
# [INFO 26-08-13 04:16:07.1878 UTC kernel.cc:1061] Use fast generic engine
# Model compiled.
# CPU times: user 5.59 s, sys: 353 ms, total: 5.94 s
# Wall time: 5.94 s

# %%
# Evaluate the model
evaluate = model.evaluate(val_ds, return_dict=True)
print()

for name, value in evaluate.items():
    print(f"{name}: {value:.4f}")
# Out:
# WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 1/1 [==============================] - ETA: 0s - loss: 0.0000e+00 - accuracy: 0.9524
# 1/1 [==============================] - 3s 3s/step - loss: 0.0000e+00 - accuracy: 0.9524
# loss: 0.0000
# accuracy: 0.9524

# %%
# Model Summary
model.summary()
# Out:
# Model: "gradient_boosted_trees_model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
# =================================================================
# Total params: 1 (1.00 Byte)
# Trainable params: 0 (0.00 Byte)
# Non-trainable params: 1 (1.00 Byte)
# _________________________________________________________________
# Type: "GRADIENT_BOOSTED_TREES"
# Task: CLASSIFICATION
# Label: "__LABEL"
#
# Input Features (14):
# 	DependenceEntropy
# 	DependenceNonUniformity
# 	DependenceNonUniformityNormalized
# 	DependenceVariance
# 	GrayLevelNonUniformity
# 	GrayLevelVariance
# 	HighGrayLevelEmphasis
# 	LargeDependenceEmphasis
# 	LargeDependenceHighGrayLevelEmphasis
# 	LargeDependenceLowGrayLevelEmphasis
# 	LowGrayLevelEmphasis
# 	SmallDependenceEmphasis
# 	SmallDependenceHighGrayLevelEmphasis
# 	SmallDependenceLowGrayLevelEmphasis
#
# Trained with weights
#
# Variable Importance: INV_MEAN_MIN_DEPTH:
#     1.                "HighGrayLevelEmphasis"  1.000000 ################
#     2. "LargeDependenceHighGrayLevelEmphasis"  0.310361 ##
#     3.                    "DependenceEntropy"  0.243028 #
#     4.                    "GrayLevelVariance"  0.222638
#     5.                 "LowGrayLevelEmphasis"  0.204910
#     6.               "GrayLevelNonUniformity"  0.195200
#     7.  "SmallDependenceLowGrayLevelEmphasis"  0.195021
#     8.              "SmallDependenceEmphasis"  0.186711
#     9.    "DependenceNonUniformityNormalized"  0.184667
#    10. "SmallDependenceHighGrayLevelEmphasis"  0.184242
#    11.              "DependenceNonUniformity"  0.183992
#    12.  "LargeDependenceLowGrayLevelEmphasis"  0.183615
#    13.                   "DependenceVariance"  0.183174
#    14.              "LargeDependenceEmphasis"  0.181927
#
# Variable Importance: NUM_AS_ROOT:
#     1. "HighGrayLevelEmphasis" 20.000000
#
# Variable Importance: NUM_NODES:
#     1. "LargeDependenceHighGrayLevelEmphasis" 108.000000 ################
#     2.                    "DependenceEntropy" 58.000000 ########
#     3.                "HighGrayLevelEmphasis" 44.000000 ######
#     4.                 "LowGrayLevelEmphasis" 33.000000 ####
#     5.                    "GrayLevelVariance" 31.000000 ####
#     6.               "GrayLevelNonUniformity" 25.000000 ###
#     7.              "SmallDependenceEmphasis" 20.000000 ##
#     8. "SmallDependenceHighGrayLevelEmphasis" 15.000000 #
#     9.  "SmallDependenceLowGrayLevelEmphasis" 13.000000 #
#    10.    "DependenceNonUniformityNormalized" 11.000000 #
#    11.                   "DependenceVariance"  8.000000
#    12.  "LargeDependenceLowGrayLevelEmphasis"  8.000000
#    13.              "DependenceNonUniformity"  7.000000
#    14.              "LargeDependenceEmphasis"  2.000000
#
# Variable Importance: SUM_SCORE:
#     1.                "HighGrayLevelEmphasis" 601.832977 ################
#     2. "LargeDependenceHighGrayLevelEmphasis" 95.713244 ##
#     3.                    "DependenceEntropy" 58.860740 #
#     4.               "GrayLevelNonUniformity" 25.507288
#     5.                    "GrayLevelVariance" 23.904948
#     6.                 "LowGrayLevelEmphasis"  9.630873
#     7. "SmallDependenceHighGrayLevelEmphasis"  9.175592
#     8.  "SmallDependenceLowGrayLevelEmphasis"  7.750349
#     9.              "SmallDependenceEmphasis"  5.696390
#    10.  "LargeDependenceLowGrayLevelEmphasis"  1.834680
#    11.              "DependenceNonUniformity"  0.772824
#    12.    "DependenceNonUniformityNormalized"  0.467809
#    13.                   "DependenceVariance"  0.366602
#    14.              "LargeDependenceEmphasis"  0.172465
#
#
#
# Loss: BINOMIAL_LOG_LIKELIHOOD
# Validation loss value: 0.646396
# Number of trees per iteration: 1
# Node format: NOT_SET
# Number of trees: 20
# Total number of nodes: 786
#
# Number of nodes by tree:
# Count: 20 Average: 39.3 StdDev: 3.96358
# Min: 33 Max: 45 Ignored: 0
# ----------------------------------------------
# [ 33, 34) 2  10.00%  10.00% ###
# [ 34, 35) 0   0.00%  10.00%
# [ 35, 36) 3  15.00%  25.00% #####
# [ 36, 37) 0   0.00%  25.00%
# [ 37, 38) 5  25.00%  50.00% ########
# [ 38, 39) 0   0.00%  50.00%
# [ 39, 40) 0   0.00%  50.00%
# [ 40, 41) 0   0.00%  50.00%
# [ 41, 42) 2  10.00%  60.00% ###
# [ 42, 43) 0   0.00%  60.00%
# [ 43, 44) 6  30.00%  90.00% ##########
# [ 44, 45) 0   0.00%  90.00%
# [ 45, 45] 2  10.00% 100.00% ###
#
# Depth by leafs:
# Count: 403 Average: 4.51613 StdDev: 0.669516
# Min: 2 Max: 5 Ignored: 0
# ----------------------------------------------
# [ 2, 3)   2   0.50%   0.50%
# [ 3, 4)  34   8.44%   8.93% #
# [ 4, 5) 121  30.02%  38.96% #####
# [ 5, 5] 246  61.04% 100.00% ##########
#
# Number of training obs by leaf:
# Count: 403 Average: 33.201 StdDev: 83.4983
# Min: 5 Max: 438 Ignored: 0
# ----------------------------------------------
# [   5,  26) 320  79.40%  79.40% ##########
# [  26,  48)  36   8.93%  88.34% #
# [  48,  70)  21   5.21%  93.55% #
# [  70,  91)   6   1.49%  95.04%
# [  91, 113)   0   0.00%  95.04%
# [ 113, 135)   0   0.00%  95.04%
# [ 135, 156)   0   0.00%  95.04%
# [ 156, 178)   0   0.00%  95.04%
# [ 178, 200)   0   0.00%  95.04%
# [ 200, 222)   0   0.00%  95.04%
# [ 222, 243)   0   0.00%  95.04%
# [ 243, 265)   0   0.00%  95.04%
# [ 265, 287)   0   0.00%  95.04%
# [ 287, 308)   0   0.00%  95.04%
# [ 308, 330)   0   0.00%  95.04%
# [ 330, 352)   5   1.24%  96.28%
# [ 352, 373)   5   1.24%  97.52%
# [ 373, 395)   1   0.25%  97.77%
# [ 395, 417)   0   0.00%  97.77%
# [ 417, 438]   9   2.23% 100.00%
#
# Attribute in nodes:
# 	108 : LargeDependenceHighGrayLevelEmphasis [NUMERICAL]
# 	58 : DependenceEntropy [NUMERICAL]
# 	44 : HighGrayLevelEmphasis [NUMERICAL]
# 	33 : LowGrayLevelEmphasis [NUMERICAL]
# 	31 : GrayLevelVariance [NUMERICAL]
# 	25 : GrayLevelNonUniformity [NUMERICAL]
# 	20 : SmallDependenceEmphasis [NUMERICAL]
# 	15 : SmallDependenceHighGrayLevelEmphasis [NUMERICAL]
# 	13 : SmallDependenceLowGrayLevelEmphasis [NUMERICAL]
# 	11 : DependenceNonUniformityNormalized [NUMERICAL]
# 	8 : LargeDependenceLowGrayLevelEmphasis [NUMERICAL]
# 	8 : DependenceVariance [NUMERICAL]
# 	7 : DependenceNonUniformity [NUMERICAL]
# 	2 : LargeDependenceEmphasis [NUMERICAL]
#
# Attribute in nodes with depth <= 0:
# 	20 : HighGrayLevelEmphasis [NUMERICAL]
#
# Attribute in nodes with depth <= 1:
# 	20 : LargeDependenceHighGrayLevelEmphasis [NUMERICAL]
# 	20 : HighGrayLevelEmphasis [NUMERICAL]
# 	10 : GrayLevelVariance [NUMERICAL]
# 	10 : DependenceEntropy [NUMERICAL]
#
# Attribute in nodes with depth <= 2:
# 	37 : LargeDependenceHighGrayLevelEmphasis [NUMERICAL]
# 	23 : DependenceEntropy [NUMERICAL]
# 	20 : HighGrayLevelEmphasis [NUMERICAL]
# 	18 : LowGrayLevelEmphasis [NUMERICAL]
# 	13 : GrayLevelNonUniformity [NUMERICAL]
# 	11 : GrayLevelVariance [NUMERICAL]
# 	8 : SmallDependenceLowGrayLevelEmphasis [NUMERICAL]
# 	2 : DependenceVariance [NUMERICAL]
# 	2 : DependenceNonUniformityNormalized [NUMERICAL]
# 	1 : SmallDependenceHighGrayLevelEmphasis [NUMERICAL]
# 	1 : LargeDependenceLowGrayLevelEmphasis [NUMERICAL]
# 	1 : LargeDependenceEmphasis [NUMERICAL]
# 	1 : DependenceNonUniformity [NUMERICAL]
#
# Attribute in nodes with depth <= 3:
# 	73 : LargeDependenceHighGrayLevelEmphasis [NUMERICAL]
# 	39 : DependenceEntropy [NUMERICAL]
# 	35 : HighGrayLevelEmphasis [NUMERICAL]
# 	25 : LowGrayLevelEmphasis [NUMERICAL]
# 	24 : GrayLevelVariance [NUMERICAL]
# 	18 : GrayLevelNonUniformity [NUMERICAL]
# 	14 : SmallDependenceEmphasis [NUMERICAL]
# 	11 : SmallDependenceLowGrayLevelEmphasis [NUMERICAL]
# 	6 : SmallDependenceHighGrayLevelEmphasis [NUMERICAL]
# 	5 : DependenceNonUniformityNormalized [NUMERICAL]
# 	3 : LargeDependenceLowGrayLevelEmphasis [NUMERICAL]
# 	3 : DependenceVariance [NUMERICAL]
# 	3 : DependenceNonUniformity [NUMERICAL]
# 	1 : LargeDependenceEmphasis [NUMERICAL]
#
# Attribute in nodes with depth <= 5:
# 	108 : LargeDependenceHighGrayLevelEmphasis [NUMERICAL]
# 	58 : DependenceEntropy [NUMERICAL]
# 	44 : HighGrayLevelEmphasis [NUMERICAL]
# 	33 : LowGrayLevelEmphasis [NUMERICAL]
# 	31 : GrayLevelVariance [NUMERICAL]
# 	25 : GrayLevelNonUniformity [NUMERICAL]
# 	20 : SmallDependenceEmphasis [NUMERICAL]
# 	15 : SmallDependenceHighGrayLevelEmphasis [NUMERICAL]
# 	13 : SmallDependenceLowGrayLevelEmphasis [NUMERICAL]
# 	11 : DependenceNonUniformityNormalized [NUMERICAL]
# 	8 : LargeDependenceLowGrayLevelEmphasis [NUMERICAL]
# 	8 : DependenceVariance [NUMERICAL]
# 	7 : DependenceNonUniformity [NUMERICAL]
# 	2 : LargeDependenceEmphasis [NUMERICAL]
#
# Condition type in nodes:
# 	383 : HigherCondition
# Condition type in nodes with depth <= 0:
# 	20 : HigherCondition
# Condition type in nodes with depth <= 1:
# 	60 : HigherCondition
# Condition type in nodes with depth <= 2:
# 	138 : HigherCondition
# Condition type in nodes with depth <= 3:
# 	260 : HigherCondition
# Condition type in nodes with depth <= 5:
# 	383 : HigherCondition
#
# Training logs:
# Number of iteration to final model: 20
# 	Iter:1 train-loss:1.210535 valid-loss:1.247822  train-accuracy:0.977960 valid-accuracy:0.888053
# 	Iter:2 train-loss:1.066585 valid-loss:1.137591  train-accuracy:0.978842 valid-accuracy:0.888053
# 	Iter:3 train-loss:0.946793 valid-loss:1.053020  train-accuracy:0.977078 valid-accuracy:0.888053
# 	Iter:4 train-loss:0.846070 valid-loss:0.987008  train-accuracy:0.985894 valid-accuracy:0.888053
# 	Iter:5 train-loss:0.759619 valid-loss:0.931178  train-accuracy:0.985013 valid-accuracy:0.888053
# 	Iter:6 train-loss:0.683975 valid-loss:0.885844  train-accuracy:0.985894 valid-accuracy:0.888053
# 	Iter:16 train-loss:0.281736 valid-loss:0.677982  train-accuracy:0.988539 valid-accuracy:0.840434
# 	Iter:26 train-loss:0.137958 valid-loss:0.709860  train-accuracy:0.991184 valid-accuracy:0.888053
# 	Iter:36 train-loss:0.074199 valid-loss:0.782936  train-accuracy:0.994710 valid-accuracy:0.888053
# 	Iter:46 train-loss:0.046034 valid-loss:0.809335  train-accuracy:0.997355 valid-accuracy:0.888053

# %%
# Model features
model.make_inspector().features()
# Out:
# ["DependenceEntropy" (1; #0),
#  "DependenceNonUniformity" (1; #1),
#  "DependenceNonUniformityNormalized" (1; #2),
#  "DependenceVariance" (1; #3),
#  "GrayLevelNonUniformity" (1; #4),
#  "GrayLevelVariance" (1; #5),
#  "HighGrayLevelEmphasis" (1; #6),
#  "LargeDependenceEmphasis" (1; #7),
#  "LargeDependenceHighGrayLevelEmphasis" (1; #8),
#  "LargeDependenceLowGrayLevelEmphasis" (1; #9),
#  "LowGrayLevelEmphasis" (1; #10),
#  "SmallDependenceEmphasis" (1; #11),
#  "SmallDependenceHighGrayLevelEmphasis" (1; #12),
#  "SmallDependenceLowGrayLevelEmphasis" (1; #13)]

# %%
# Feature importance
model.make_inspector().variable_importances()
# Out:
# {'INV_MEAN_MIN_DEPTH': [("HighGrayLevelEmphasis" (1; #6), 1.0),
#   ("LargeDependenceHighGrayLevelEmphasis" (1; #8), 0.31036094342258314),
#   ("DependenceEntropy" (1; #0), 0.24302828430063644),
#   ("GrayLevelVariance" (1; #5), 0.22263849066661429),
#   ("LowGrayLevelEmphasis" (1; #10), 0.20491037106369187),
#   ("GrayLevelNonUniformity" (1; #4), 0.1952002045373869),
#   ("SmallDependenceLowGrayLevelEmphasis" (1; #13), 0.19502104352835067),
#   ("SmallDependenceEmphasis" (1; #11), 0.186711014333155),
#   ("DependenceNonUniformityNormalized" (1; #2), 0.184666617622956),
#   ("SmallDependenceHighGrayLevelEmphasis" (1; #12), 0.18424160055373504),
#   ("DependenceNonUniformity" (1; #1), 0.1839916374835346),
#   ("LargeDependenceLowGrayLevelEmphasis" (1; #9), 0.18361541602270381),
#   ("DependenceVariance" (1; #3), 0.18317350882707997),
#   ("LargeDependenceEmphasis" (1; #7), 0.18192667441344657)],
#  'NUM_AS_ROOT': [("HighGrayLevelEmphasis" (1; #6), 20.0)],
#  'SUM_SCORE': [("HighGrayLevelEmphasis" (1; #6), 601.8329767271642),
#   ("LargeDependenceHighGrayLevelEmphasis" (1; #8), 95.71324362488454),
#   ("DependenceEntropy" (1; #0), 58.86073967382161),
#   ("GrayLevelNonUniformity" (1; #4), 25.50728824355862),
#   ("GrayLevelVariance" (1; #5), 23.90494847027958),
#   ("LowGrayLevelEmphasis" (1; #10), 9.630872951223434),
#   ("SmallDependenceHighGrayLevelEmphasis" (1; #12), 9.175592130317645),
#   ("SmallDependenceLowGrayLevelEmphasis" (1; #13), 7.750349321141331),
#   ("SmallDependenceEmphasis" (1; #11), 5.696389513554729),
#   ("LargeDependenceLowGrayLevelEmphasis" (1; #9), 1.8346801988013843),
#   ("DependenceNonUniformity" (1; #1), 0.7728243413465756),
#   ("DependenceNonUniformityNormalized" (1; #2), 0.46780914582784894),
#   ("DependenceVariance" (1; #3), 0.3666023265439646),
#   ("LargeDependenceEmphasis" (1; #7), 0.17246513454537565)],
#  'NUM_NODES': [("LargeDependenceHighGrayLevelEmphasis" (1; #8), 108.0),
#   ("DependenceEntropy" (1; #0), 58.0),
#   ("HighGrayLevelEmphasis" (1; #6), 44.0),
#   ("LowGrayLevelEmphasis" (1; #10), 33.0),
#   ("GrayLevelVariance" (1; #5), 31.0),
#   ("GrayLevelNonUniformity" (1; #4), 25.0),
#   ("SmallDependenceEmphasis" (1; #11), 20.0),
#   ("SmallDependenceHighGrayLevelEmphasis" (1; #12), 15.0),
#   ("SmallDependenceLowGrayLevelEmphasis" (1; #13), 13.0),
#   ("DependenceNonUniformityNormalized" (1; #2), 11.0),
#   ("DependenceVariance" (1; #3), 8.0),
#   ("LargeDependenceLowGrayLevelEmphasis" (1; #9), 8.0),
#   ("DependenceNonUniformity" (1; #1), 7.0),
#   ("LargeDependenceEmphasis" (1; #7), 2.0)]}

# %%
# Model self evaluation
model.make_inspector().evaluation()
# Out:
# Evaluation(num_examples=None, accuracy=0.8404344320297241, loss=0.6463958024978638, rmse=None, ndcg=None, aucs=None, auuc=None, qini=None)

# %%
logs = model.make_inspector().training_logs()

plt.figure(figsize=(12, 4))
plt.subplot(1, 2, 1)
plt.plot([log.num_trees for log in logs], [log.evaluation.accuracy for log in logs])
plt.xlabel("Number of trees")
plt.ylabel("Accuracy (out-of-bag)")
plt.subplot(1, 2, 2)
plt.plot([log.num_trees for log in logs], [log.evaluation.loss for log in logs])
plt.xlabel("Number of trees")
plt.ylabel("Logloss (out-of-bag)")
plt.show()

# %% [markdown]
# Calculate the score of our hold-out validation dataset

# %%
predictions = model.predict(val_ds)
y_true      = validation_data["label"]

from sklearn.metrics import roc_auc_score
ROC_AUC = roc_auc_score(y_true, predictions)
print("The ROC AUC score is %.5f" % ROC_AUC )
# Out:
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 58ms/step
# The ROC AUC score is 0.97659

# %%
# Compute binary classification metrics with sklearn
import numpy as np
from sklearn.metrics import (
    accuracy_score,
    precision_score,
    recall_score,
    f1_score,
    roc_auc_score,
    average_precision_score,
    confusion_matrix,
    classification_report,
    matthews_corrcoef,
    log_loss,
    brier_score_loss,
)

# Get predictions (probabilities or class labels)
preds = model.predict(test_ds)
# If model outputs probabilities, convert to labels by threshold 0.5
if preds.ndim == 2:
    # For TFDF classification, preds may be class probabilities with shape (N, 2)
    if preds.shape[1] == 2:
        pos_probs = preds[:, 1]
    else:
        # If single-probability column (positive class)
        pos_probs = preds[:, -1]
    y_pred = (pos_probs >= 0.5).astype(int)
else:
    # Already class labels
    y_pred = preds.astype(int)
    pos_probs = None

# Ground truth labels (must be 0/1 integers)
y_true = test_data["label"].astype(int).to_numpy()

# Core metrics
metrics = {}
metrics["accuracy"] = accuracy_score(y_true, y_pred)
metrics["precision"] = precision_score(y_true, y_pred, zero_division=0)
metrics["recall"] = recall_score(y_true, y_pred, zero_division=0)
metrics["f1"] = f1_score(y_true, y_pred, zero_division=0)
metrics["mcc"] = matthews_corrcoef(y_true, y_pred)

# Probabilistic metrics (only if we have probabilities)
if pos_probs is not None:
    metrics["roc_auc"] = roc_auc_score(y_true, pos_probs)
    metrics["pr_auc"] = average_precision_score(y_true, pos_probs)
    metrics["log_loss"] = log_loss(y_true, pos_probs, labels=[0,1])
    metrics["brier_score"] = brier_score_loss(y_true, pos_probs)

# Confusion matrix and detailed report
cm = confusion_matrix(y_true, y_pred, labels=[0,1])
report = classification_report(y_true, y_pred, digits=4)

print("Sklearn binary metrics:")
for k, v in metrics.items():
    print(f"{k}: {v:.4f}")
print("\nConfusion matrix:\n", cm)
print("\nClassification report:\n", report)
# Out:
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 63ms/step
# Sklearn binary metrics:
# accuracy: 0.9764
# precision: 0.8421
# recall: 0.8889
# f1: 0.8649
# mcc: 0.8523
# roc_auc: 0.9792
# pr_auc: 0.8771
# log_loss: 0.1410
# brier_score: 0.0296
#
# Confusion matrix:
#  [[191   3]
#  [  2  16]]
#
# Classification report:
#                precision    recall  f1-score   support
#
#            0     0.9896    0.9845    0.9871       194
#            1     0.8421    0.8889    0.8649        18
#
#     accuracy                         0.9764       212
#    macro avg     0.9159    0.9367    0.9260       212
# weighted avg     0.9771    0.9764    0.9767       212
