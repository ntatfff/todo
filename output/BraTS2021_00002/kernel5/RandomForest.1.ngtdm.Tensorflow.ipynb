# %%
# Import packages and modules
import numpy  as np
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow_decision_forests as tfdf

from sklearn.model_selection import train_test_split
# Out:
# 2026-08-13 04:28:55.213595: I tensorflow/core/util/port.cc:113] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2026-08-13 04:28:55.600018: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2026-08-13 04:29:00.551581: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
# Check the version of TensorFlow Decision Forests
print("Found TensorFlow Decision Forests v" + tfdf.__version__)
# Out:
# Found TensorFlow Decision Forests v1.9.1

# %%
datasetPath = 'dataset/firstorder/kernel5/dataset.csv'

# %%
# Parameters
datasetPath = "dataset/ngtdm/kernel5/1.dataset.csv"

# %%
# train/validation/test = 70/10/20
dataset = pd.read_csv(datasetPath)

train_data, temp_data = train_test_split(dataset, test_size=0.3, random_state=42)
validation_data, test_data = train_test_split(temp_data, test_size=2/3, random_state=42)

# %%
from sklearn.utils.class_weight import compute_class_weight

# tinh class weight tren tap train
classes = np.array([0, 1])
weights = compute_class_weight(class_weight="balanced", classes=classes, y=train_data["label"])
class_weight = {0: weights[0], 1: weights[1]}

# gan sample_weight cho tung dong
train_data["sample_weight"] = train_data["label"].map(class_weight)
validation_data["sample_weight"] = validation_data["label"].map(class_weight)
test_data["sample_weight"] = test_data["label"].map(class_weight)

# Convert the dataset into a TensorFlow dataset.
train_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    train_data, label="label", weight="sample_weight"
)         
val_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    validation_data, label="label", weight="sample_weight"
)
test_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    test_data, label="label", weight="sample_weight"
)
# Out:
# 2026-08-13 04:29:14.526887: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:984] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2026-08-13 04:29:14.528429: W tensorflow/core/common_runtime/gpu/gpu_device.cc:2251] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...

# %%
import keras

# %%
# %%time

# Train a Random Forest model.
model = tfdf.keras.RandomForestModel()

# Add evaluation metrics
model.compile(
    metrics=["accuracy"]
)
model.fit(x=train_ds)

# # Train a Gradient Boosted Trees model.
# model = tfdf.keras.GradientBoostedTreesModel(num_trees=1500)
# model.fit(train_ds)
# Out:
# Use /tmp/tmpums9eu1c as temporary training directory
# Reading training dataset...
# Training dataset read in 0:00:02.545900. Found 737 examples.
# Training model...
# Model trained in 0:00:00.076782
# Compiling model...
# [INFO 26-08-13 04:29:17.2799 UTC kernel.cc:1233] Loading model from path /tmp/tmpums9eu1c/model/ with prefix 6ed6afed49024d30
# [INFO 26-08-13 04:29:17.2982 UTC decision_forest.cc:734] Model loaded with 300 root(s), 13754 node(s), and 5 input feature(s).
# [INFO 26-08-13 04:29:17.2982 UTC abstract_model.cc:1362] Engine "RandomForestOptPred" built
# [INFO 26-08-13 04:29:17.2982 UTC kernel.cc:1061] Use fast generic engine
# Model compiled.
# CPU times: user 5.44 s, sys: 180 ms, total: 5.62 s
# Wall time: 5.87 s

# %%
# Evaluate the model
evaluate = model.evaluate(val_ds, return_dict=True)
print()

for name, value in evaluate.items():
    print(f"{name}: {value:.4f}")
# Out:
# WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 1/1 [==============================] - ETA: 0s - loss: 0.0000e+00 - accuracy: 0.9238
# 1/1 [==============================] - 3s 3s/step - loss: 0.0000e+00 - accuracy: 0.9238
# loss: 0.0000
# accuracy: 0.9238

# %%
# Model Summary
model.summary()
# Out:
# Model: "random_forest_model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
# =================================================================
# Total params: 1 (1.00 Byte)
# Trainable params: 0 (0.00 Byte)
# Non-trainable params: 1 (1.00 Byte)
# _________________________________________________________________
# Type: "RANDOM_FOREST"
# Task: CLASSIFICATION
# Label: "__LABEL"
#
# Input Features (5):
# 	Busyness
# 	Coarseness
# 	Complexity
# 	Contrast
# 	Strength
#
# Trained with weights
#
# Variable Importance: INV_MEAN_MIN_DEPTH:
#     1.   "Busyness"  0.717163 ################
#     2. "Coarseness"  0.271178 ##
#     3. "Complexity"  0.251123 #
#     4.   "Strength"  0.243509 #
#     5.   "Contrast"  0.192262
#
# Variable Importance: NUM_AS_ROOT:
#     1.   "Busyness" 237.000000 ################
#     2. "Coarseness" 62.000000 ####
#     3.   "Strength"  1.000000
#
# Variable Importance: NUM_NODES:
#     1.   "Busyness" 2094.000000 ################
#     2.   "Strength" 1423.000000 #######
#     3. "Complexity" 1376.000000 #######
#     4. "Coarseness" 1035.000000 ##
#     5.   "Contrast" 799.000000
#
# Variable Importance: SUM_SCORE:
#     1.   "Busyness" 70613.181106 ################
#     2. "Complexity" 24625.929187 ####
#     3.   "Strength" 19411.502056 ###
#     4. "Coarseness" 17492.579204 ##
#     5.   "Contrast" 7290.383016
#
#
#
# Winner takes all: true
# Out-of-bag evaluation: accuracy:0.894975 logloss:0.253096
# Number of trees: 300
# Total number of nodes: 13754
#
# Number of nodes by tree:
# Count: 300 Average: 45.8467 StdDev: 4.65222
# Min: 35 Max: 63 Ignored: 0
# ----------------------------------------------
# [ 35, 36)  3   1.00%   1.00% #
# [ 36, 37)  0   0.00%   1.00%
# [ 37, 39)  9   3.00%   4.00% ##
# [ 39, 40) 23   7.67%  11.67% ####
# [ 40, 42) 23   7.67%  19.33% ####
# [ 42, 43)  0   0.00%  19.33%
# [ 43, 45) 45  15.00%  34.33% ########
# [ 45, 46) 56  18.67%  53.00% ##########
# [ 46, 48) 43  14.33%  67.33% ########
# [ 48, 49)  0   0.00%  67.33%
# [ 49, 50) 47  15.67%  83.00% ########
# [ 50, 52) 25   8.33%  91.33% ####
# [ 52, 53)  0   0.00%  91.33%
# [ 53, 55) 16   5.33%  96.67% ###
# [ 55, 56)  4   1.33%  98.00% #
# [ 56, 58)  3   1.00%  99.00% #
# [ 58, 59)  0   0.00%  99.00%
# [ 59, 61)  1   0.33%  99.33%
# [ 61, 62)  1   0.33%  99.67%
# [ 62, 63]  1   0.33% 100.00%
#
# Depth by leafs:
# Count: 7027 Average: 5.06902 StdDev: 1.31966
# Min: 2 Max: 11 Ignored: 0
# ----------------------------------------------
# [  2,  3)   36   0.51%   0.51%
# [  3,  4)  635   9.04%   9.55% ###
# [  4,  5) 1891  26.91%  36.46% #########
# [  5,  6) 2094  29.80%  66.26% ##########
# [  6,  7) 1396  19.87%  86.12% #######
# [  7,  8)  646   9.19%  95.32% ###
# [  8,  9)  259   3.69%  99.00% #
# [  9, 10)   63   0.90%  99.90%
# [ 10, 11)    5   0.07%  99.97%
# [ 11, 11]    2   0.03% 100.00%
#
# Number of training obs by leaf:
# Count: 7027 Average: 31.4644 StdDev: 92.7273
# Min: 5 Max: 531 Ignored: 0
# ----------------------------------------------
# [   5,  31) 6164  87.72%  87.72% ##########
# [  31,  57)  455   6.48%  94.19% #
# [  57,  84)   74   1.05%  95.25%
# [  84, 110)   11   0.16%  95.40%
# [ 110, 136)    8   0.11%  95.52%
# [ 136, 163)    2   0.03%  95.55%
# [ 163, 189)    1   0.01%  95.56%
# [ 189, 215)    5   0.07%  95.63%
# [ 215, 242)    4   0.06%  95.69%
# [ 242, 268)    4   0.06%  95.74%
# [ 268, 294)    5   0.07%  95.82%
# [ 294, 321)    4   0.06%  95.87%
# [ 321, 347)    5   0.07%  95.94%
# [ 347, 373)    1   0.01%  95.96%
# [ 373, 400)    7   0.10%  96.06%
# [ 400, 426)   24   0.34%  96.40%
# [ 426, 452)   40   0.57%  96.97%
# [ 452, 479)   85   1.21%  98.18%
# [ 479, 505)   97   1.38%  99.56%
# [ 505, 531]   31   0.44% 100.00%
#
# Attribute in nodes:
# 	2094 : Busyness [NUMERICAL]
# 	1423 : Strength [NUMERICAL]
# 	1376 : Complexity [NUMERICAL]
# 	1035 : Coarseness [NUMERICAL]
# 	799 : Contrast [NUMERICAL]
#
# Attribute in nodes with depth <= 0:
# 	237 : Busyness [NUMERICAL]
# 	62 : Coarseness [NUMERICAL]
# 	1 : Strength [NUMERICAL]
#
# Attribute in nodes with depth <= 1:
# 	429 : Busyness [NUMERICAL]
# 	176 : Complexity [NUMERICAL]
# 	176 : Coarseness [NUMERICAL]
# 	97 : Strength [NUMERICAL]
# 	22 : Contrast [NUMERICAL]
#
# Attribute in nodes with depth <= 2:
# 	768 : Busyness [NUMERICAL]
# 	510 : Complexity [NUMERICAL]
# 	431 : Strength [NUMERICAL]
# 	247 : Coarseness [NUMERICAL]
# 	108 : Contrast [NUMERICAL]
#
# Attribute in nodes with depth <= 3:
# 	1332 : Busyness [NUMERICAL]
# 	802 : Strength [NUMERICAL]
# 	790 : Complexity [NUMERICAL]
# 	523 : Coarseness [NUMERICAL]
# 	310 : Contrast [NUMERICAL]
#
# Attribute in nodes with depth <= 5:
# 	1968 : Busyness [NUMERICAL]
# 	1299 : Strength [NUMERICAL]
# 	1266 : Complexity [NUMERICAL]
# 	933 : Coarseness [NUMERICAL]
# 	682 : Contrast [NUMERICAL]
#
# Condition type in nodes:
# 	6727 : HigherCondition
# Condition type in nodes with depth <= 0:
# 	300 : HigherCondition
# Condition type in nodes with depth <= 1:
# 	900 : HigherCondition
# Condition type in nodes with depth <= 2:
# 	2064 : HigherCondition
# Condition type in nodes with depth <= 3:
# 	3757 : HigherCondition
# Condition type in nodes with depth <= 5:
# 	6148 : HigherCondition
# Node format: NOT_SET
#
# Training OOB:
# 	trees: 1, Out-of-bag evaluation: accuracy:0.854035 logloss:5.26111
# 	trees: 13, Out-of-bag evaluation: accuracy:0.790461 logloss:2.27738
# 	trees: 23, Out-of-bag evaluation: accuracy:0.879481 logloss:1.03578
# 	trees: 33, Out-of-bag evaluation: accuracy:0.864775 logloss:0.868032
# 	trees: 43, Out-of-bag evaluation: accuracy:0.863201 logloss:0.812406
# 	trees: 53, Out-of-bag evaluation: accuracy:0.868102 logloss:0.818497
# 	trees: 64, Out-of-bag evaluation: accuracy:0.884383 logloss:0.808192
# 	trees: 74, Out-of-bag evaluation: accuracy:0.873004 logloss:0.459378
# 	trees: 84, Out-of-bag evaluation: accuracy:0.88771 logloss:0.457803
# 	trees: 94, Out-of-bag evaluation: accuracy:0.88771 logloss:0.269618
# 	trees: 104, Out-of-bag evaluation: accuracy:0.88771 logloss:0.270106
# 	trees: 114, Out-of-bag evaluation: accuracy:0.877906 logloss:0.268611
# 	trees: 124, Out-of-bag evaluation: accuracy:0.892612 logloss:0.266026
# 	trees: 134, Out-of-bag evaluation: accuracy:0.882808 logloss:0.264777
# 	trees: 144, Out-of-bag evaluation: accuracy:0.883596 logloss:0.264932
# 	trees: 155, Out-of-bag evaluation: accuracy:0.888498 logloss:0.261582
# 	trees: 166, Out-of-bag evaluation: accuracy:0.892612 logloss:0.261081
# 	trees: 177, Out-of-bag evaluation: accuracy:0.8934 logloss:0.260399
# 	trees: 187, Out-of-bag evaluation: accuracy:0.8934 logloss:0.259903
# 	trees: 197, Out-of-bag evaluation: accuracy:0.8934 logloss:0.26014
# 	trees: 207, Out-of-bag evaluation: accuracy:0.888498 logloss:0.259702
# 	trees: 217, Out-of-bag evaluation: accuracy:0.88771 logloss:0.260256
# 	trees: 231, Out-of-bag evaluation: accuracy:0.88771 logloss:0.257851
# 	trees: 241, Out-of-bag evaluation: accuracy:0.894187 logloss:0.258203
# 	trees: 251, Out-of-bag evaluation: accuracy:0.899089 logloss:0.257173
# 	trees: 261, Out-of-bag evaluation: accuracy:0.899089 logloss:0.256941
# 	trees: 271, Out-of-bag evaluation: accuracy:0.899089 logloss:0.257978
# 	trees: 281, Out-of-bag evaluation: accuracy:0.899089 logloss:0.256145
# 	trees: 291, Out-of-bag evaluation: accuracy:0.894975 logloss:0.253187
# 	trees: 300, Out-of-bag evaluation: accuracy:0.894975 logloss:0.253096

# %%
# Model features
model.make_inspector().features()
# Out:
# ["Busyness" (1; #0),
#  "Coarseness" (1; #1),
#  "Complexity" (1; #2),
#  "Contrast" (1; #3),
#  "Strength" (1; #4)]

# %%
# Feature importance
model.make_inspector().variable_importances()
# Out:
# {'INV_MEAN_MIN_DEPTH': [("Busyness" (1; #0), 0.7171630034207477),
#   ("Coarseness" (1; #1), 0.2711780359059006),
#   ("Complexity" (1; #2), 0.2511227550298806),
#   ("Strength" (1; #4), 0.2435089025942399),
#   ("Contrast" (1; #3), 0.19226195508319294)],
#  'NUM_AS_ROOT': [("Busyness" (1; #0), 237.0),
#   ("Coarseness" (1; #1), 62.0),
#   ("Strength" (1; #4), 1.0)],
#  'SUM_SCORE': [("Busyness" (1; #0), 70613.18110639803),
#   ("Complexity" (1; #2), 24625.929186839327),
#   ("Strength" (1; #4), 19411.50205599781),
#   ("Coarseness" (1; #1), 17492.579204356352),
#   ("Contrast" (1; #3), 7290.3830156925405)],
#  'NUM_NODES': [("Busyness" (1; #0), 2094.0),
#   ("Strength" (1; #4), 1423.0),
#   ("Complexity" (1; #2), 1376.0),
#   ("Coarseness" (1; #1), 1035.0),
#   ("Contrast" (1; #3), 799.0)]}

# %%
# Model self evaluation
model.make_inspector().evaluation()
# Out:
# Evaluation(num_examples=737, accuracy=0.8949745245870774, loss=0.2530963005246828, rmse=None, ndcg=None, aucs=None, auuc=None, qini=None)

# %%
logs = model.make_inspector().training_logs()

plt.figure(figsize=(12, 4))
plt.subplot(1, 2, 1)
plt.plot([log.num_trees for log in logs], [log.evaluation.accuracy for log in logs])
plt.xlabel("Number of trees")
plt.ylabel("Accuracy (out-of-bag)")
plt.subplot(1, 2, 2)
plt.plot([log.num_trees for log in logs], [log.evaluation.loss for log in logs])
plt.xlabel("Number of trees")
plt.ylabel("Logloss (out-of-bag)")
plt.show()

# %% [markdown]
# Calculate the score of our hold-out validation dataset

# %%
predictions = model.predict(val_ds)
y_true      = validation_data["label"]

from sklearn.metrics import roc_auc_score
ROC_AUC = roc_auc_score(y_true, predictions)
print("The ROC AUC score is %.5f" % ROC_AUC )
# Out:
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 58ms/step
# The ROC AUC score is 0.96557

# %%
# Compute binary classification metrics with sklearn
import numpy as np
from sklearn.metrics import (
    accuracy_score,
    precision_score,
    recall_score,
    f1_score,
    roc_auc_score,
    average_precision_score,
    confusion_matrix,
    classification_report,
    matthews_corrcoef,
    log_loss,
    brier_score_loss,
)

# Get predictions (probabilities or class labels)
preds = model.predict(test_ds)
# If model outputs probabilities, convert to labels by threshold 0.5
if preds.ndim == 2:
    # For TFDF classification, preds may be class probabilities with shape (N, 2)
    if preds.shape[1] == 2:
        pos_probs = preds[:, 1]
    else:
        # If single-probability column (positive class)
        pos_probs = preds[:, -1]
    y_pred = (pos_probs >= 0.5).astype(int)
else:
    # Already class labels
    y_pred = preds.astype(int)
    pos_probs = None

# Ground truth labels (must be 0/1 integers)
y_true = test_data["label"].astype(int).to_numpy()

# Core metrics
metrics = {}
metrics["accuracy"] = accuracy_score(y_true, y_pred)
metrics["precision"] = precision_score(y_true, y_pred, zero_division=0)
metrics["recall"] = recall_score(y_true, y_pred, zero_division=0)
metrics["f1"] = f1_score(y_true, y_pred, zero_division=0)
metrics["mcc"] = matthews_corrcoef(y_true, y_pred)

# Probabilistic metrics (only if we have probabilities)
if pos_probs is not None:
    metrics["roc_auc"] = roc_auc_score(y_true, pos_probs)
    metrics["pr_auc"] = average_precision_score(y_true, pos_probs)
    metrics["log_loss"] = log_loss(y_true, pos_probs, labels=[0,1])
    metrics["brier_score"] = brier_score_loss(y_true, pos_probs)

# Confusion matrix and detailed report
cm = confusion_matrix(y_true, y_pred, labels=[0,1])
report = classification_report(y_true, y_pred, digits=4)

print("Sklearn binary metrics:")
for k, v in metrics.items():
    print(f"{k}: {v:.4f}")
print("\nConfusion matrix:\n", cm)
print("\nClassification report:\n", report)
# Out:
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 60ms/step
# Sklearn binary metrics:
# accuracy: 0.8962
# precision: 0.5000
# recall: 0.8636
# f1: 0.6333
# mcc: 0.6072
# roc_auc: 0.9434
# pr_auc: 0.6227
# log_loss: 0.2303
# brier_score: 0.0756
#
# Confusion matrix:
#  [[171  19]
#  [  3  19]]
#
# Classification report:
#                precision    recall  f1-score   support
#
#            0     0.9828    0.9000    0.9396       190
#            1     0.5000    0.8636    0.6333        22
#
#     accuracy                         0.8962       212
#    macro avg     0.7414    0.8818    0.7864       212
# weighted avg     0.9327    0.8962    0.9078       212
