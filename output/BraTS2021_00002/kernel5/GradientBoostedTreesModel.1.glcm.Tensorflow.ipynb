# %%
# Import packages and modules
import numpy  as np
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow_decision_forests as tfdf

from sklearn.model_selection import train_test_split
# Out:
# 2026-08-13 04:15:06.691553: I tensorflow/core/util/port.cc:113] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2026-08-13 04:15:07.072122: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2026-08-13 04:15:11.782191: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
# Check the version of TensorFlow Decision Forests
print("Found TensorFlow Decision Forests v" + tfdf.__version__)
# Out:
# Found TensorFlow Decision Forests v1.9.1

# %%
datasetPath = 'dataset/firstorder/kernel5/dataset.csv'

# %%
# Parameters
datasetPath = "dataset/glcm/kernel5/1.dataset.csv"

# %%
# train/validation/test = 70/10/20
dataset = pd.read_csv(datasetPath)

train_data, temp_data = train_test_split(dataset, test_size=0.3, random_state=42)
validation_data, test_data = train_test_split(temp_data, test_size=2/3, random_state=42)

# %%
from sklearn.utils.class_weight import compute_class_weight

# tinh class weight tren tap train
classes = np.array([0, 1])
weights = compute_class_weight(class_weight="balanced", classes=classes, y=train_data["label"])
class_weight = {0: weights[0], 1: weights[1]}

# gan sample_weight cho tung dong
train_data["sample_weight"] = train_data["label"].map(class_weight)
validation_data["sample_weight"] = validation_data["label"].map(class_weight)
test_data["sample_weight"] = test_data["label"].map(class_weight)

# Convert the dataset into a TensorFlow dataset.
train_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    train_data, label="label", weight="sample_weight"
)         
val_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    validation_data, label="label", weight="sample_weight"
)
test_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    test_data, label="label", weight="sample_weight"
)
# Out:
# 2026-08-13 04:15:26.525894: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:984] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2026-08-13 04:15:26.527796: W tensorflow/core/common_runtime/gpu/gpu_device.cc:2251] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...

# %%
import keras

# %%
# %%time

# Train a Gradient Boosted Trees model.
model = tfdf.keras.GradientBoostedTreesModel()

# Add evaluation metrics
model.compile(
    metrics=["accuracy"]
)
model.fit(x=train_ds)

# # Train a Gradient Boosted Trees model.
# model = tfdf.keras.GradientBoostedTreesModel(num_trees=1500)
# model.fit(train_ds)
# Out:
# Use /tmp/tmp31pku87t as temporary training directory
# Reading training dataset...
# [WARNING 26-08-13 04:15:26.6938 UTC gradient_boosted_trees.cc:1840] "goss_alpha" set but "sampling_method" not equal to "GOSS".
# [WARNING 26-08-13 04:15:26.6940 UTC gradient_boosted_trees.cc:1851] "goss_beta" set but "sampling_method" not equal to "GOSS".
# [WARNING 26-08-13 04:15:26.6940 UTC gradient_boosted_trees.cc:1865] "selective_gradient_boosting_ratio" set but "sampling_method" not equal to "SELGB".
# Training dataset read in 0:00:02.646003. Found 737 examples.
# Training model...
# Model trained in 0:00:00.313187
# Compiling model...
# [INFO 26-08-13 04:15:29.6793 UTC kernel.cc:1233] Loading model from path /tmp/tmp31pku87t/model/ with prefix 15311615c2ea4bd5
# [INFO 26-08-13 04:15:29.6816 UTC quick_scorer_extended.cc:911] The binary was compiled without AVX2 support, but your CPU supports it. Enable it for faster model inference.
# [INFO 26-08-13 04:15:29.6817 UTC abstract_model.cc:1362] Engine "GradientBoostedTreesQuickScorerExtended" built
# [INFO 26-08-13 04:15:29.6817 UTC kernel.cc:1061] Use fast generic engine
# Model compiled.
# CPU times: user 5.82 s, sys: 479 ms, total: 6.3 s
# Wall time: 6.15 s

# %%
# Evaluate the model
evaluate = model.evaluate(val_ds, return_dict=True)
print()

for name, value in evaluate.items():
    print(f"{name}: {value:.4f}")
# Out:
# WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 1/1 [==============================] - ETA: 0s - loss: 0.0000e+00 - accuracy: 0.9333
# 1/1 [==============================] - 3s 3s/step - loss: 0.0000e+00 - accuracy: 0.9333
# loss: 0.0000
# accuracy: 0.9333

# %%
# Model Summary
model.summary()
# Out:
# Model: "gradient_boosted_trees_model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
# =================================================================
# Total params: 1 (1.00 Byte)
# Trainable params: 0 (0.00 Byte)
# Non-trainable params: 1 (1.00 Byte)
# _________________________________________________________________
# Type: "GRADIENT_BOOSTED_TREES"
# Task: CLASSIFICATION
# Label: "__LABEL"
#
# Input Features (24):
# 	Autocorrelation
# 	ClusterProminence
# 	ClusterShade
# 	ClusterTendency
# 	Contrast
# 	Correlation
# 	DifferenceAverage
# 	DifferenceEntropy
# 	DifferenceVariance
# 	Id
# 	Idm
# 	Idmn
# 	Idn
# 	Imc1
# 	Imc2
# 	InverseVariance
# 	JointAverage
# 	JointEnergy
# 	JointEntropy
# 	MCC
# 	MaximumProbability
# 	SumAverage
# 	SumEntropy
# 	SumSquares
#
# Trained with weights
#
# Variable Importance: INV_MEAN_MIN_DEPTH:
#     1.    "Autocorrelation"  1.000000 ################
#     2.        "Correlation"  0.253211 #
#     3. "DifferenceVariance"  0.205553
#     4.                "Idm"  0.204231
#     5.               "Imc2"  0.204169
#     6.       "JointAverage"  0.202493
#     7.         "SumAverage"  0.200841
#     8.  "DifferenceEntropy"  0.192107
#     9.               "Imc1"  0.190327
#    10.    "InverseVariance"  0.188285
#    11.       "ClusterShade"  0.187092
#    12.                "MCC"  0.185930
#    13. "MaximumProbability"  0.185340
#    14.                 "Id"  0.184676
#    15.         "SumSquares"  0.181482
#    16.    "ClusterTendency"  0.180801
#    17.                "Idn"  0.180433
#    18.         "SumEntropy"  0.180333
#    19.       "JointEntropy"  0.180083
#    20.           "Contrast"  0.179927
#    21.  "ClusterProminence"  0.179747
#    22.               "Idmn"  0.179543
#    23.  "DifferenceAverage"  0.178603
#    24.        "JointEnergy"  0.178348
#
# Variable Importance: NUM_AS_ROOT:
#     1. "Autocorrelation" 26.000000
#
# Variable Importance: NUM_NODES:
#     1.    "Autocorrelation" 86.000000 ################
#     2.       "JointAverage" 41.000000 #######
#     3.        "Correlation" 40.000000 #######
#     4.                "Idm" 38.000000 ######
#     5.         "SumAverage" 36.000000 ######
#     6.               "Imc2" 32.000000 #####
#     7.       "ClusterShade" 31.000000 #####
#     8.  "DifferenceEntropy" 28.000000 ####
#     9. "DifferenceVariance" 28.000000 ####
#    10.                "MCC" 27.000000 ####
#    11.    "InverseVariance" 26.000000 ####
#    12.               "Imc1" 22.000000 ###
#    13. "MaximumProbability" 22.000000 ###
#    14.                 "Id" 16.000000 ##
#    15.       "JointEntropy" 11.000000 #
#    16.               "Idmn" 10.000000 #
#    17.         "SumSquares" 10.000000 #
#    18.  "ClusterProminence"  9.000000 #
#    19.         "SumEntropy"  9.000000 #
#    20.                "Idn"  8.000000 #
#    21.    "ClusterTendency"  5.000000
#    22.           "Contrast"  4.000000
#    23.  "DifferenceAverage"  3.000000
#    24.        "JointEnergy"  2.000000
#
# Variable Importance: SUM_SCORE:
#     1.    "Autocorrelation" 628.506677 ################
#     2.        "Correlation" 32.270352
#     3.         "SumAverage" 28.582024
#     4.       "JointAverage" 26.402749
#     5.                "Idm" 20.177659
#     6.  "DifferenceEntropy" 18.894013
#     7. "MaximumProbability" 17.568874
#     8. "DifferenceVariance" 16.142102
#     9.    "InverseVariance" 15.752344
#    10.                 "Id" 14.690063
#    11.               "Imc1" 13.807852
#    12.               "Imc2" 10.352154
#    13.                "MCC"  7.753803
#    14.       "ClusterShade"  7.704264
#    15.       "JointEntropy"  6.491387
#    16.  "DifferenceAverage"  2.937866
#    17.         "SumEntropy"  1.858715
#    18.                "Idn"  1.530459
#    19.         "SumSquares"  1.385796
#    20.    "ClusterTendency"  1.312621
#    21.        "JointEnergy"  0.566774
#    22.               "Idmn"  0.507099
#    23.           "Contrast"  0.400261
#    24.  "ClusterProminence"  0.292687
#
#
#
# Loss: BINOMIAL_LOG_LIKELIHOOD
# Validation loss value: 0.477005
# Number of trees per iteration: 1
# Node format: NOT_SET
# Number of trees: 26
# Total number of nodes: 1114
#
# Number of nodes by tree:
# Count: 26 Average: 42.8462 StdDev: 5.65476
# Min: 33 Max: 55 Ignored: 0
# ----------------------------------------------
# [ 33, 34) 1   3.85%   3.85% ##
# [ 34, 35) 0   0.00%   3.85%
# [ 35, 36) 3  11.54%  15.38% #####
# [ 36, 37) 0   0.00%  15.38%
# [ 37, 38) 4  15.38%  30.77% #######
# [ 38, 39) 0   0.00%  30.77%
# [ 39, 41) 0   0.00%  30.77%
# [ 41, 42) 2   7.69%  38.46% ###
# [ 42, 43) 0   0.00%  38.46%
# [ 43, 44) 3  11.54%  50.00% #####
# [ 44, 45) 0   0.00%  50.00%
# [ 45, 46) 6  23.08%  73.08% ##########
# [ 46, 47) 0   0.00%  73.08%
# [ 47, 49) 3  11.54%  84.62% #####
# [ 49, 50) 2   7.69%  92.31% ###
# [ 50, 51) 0   0.00%  92.31%
# [ 51, 52) 0   0.00%  92.31%
# [ 52, 53) 0   0.00%  92.31%
# [ 53, 54) 1   3.85%  96.15% ##
# [ 54, 55] 1   3.85% 100.00% ##
#
# Depth by leafs:
# Count: 570 Average: 4.62982 StdDev: 0.628131
# Min: 2 Max: 5 Ignored: 0
# ----------------------------------------------
# [ 2, 3)   5   0.88%   0.88%
# [ 3, 4)  31   5.44%   6.32% #
# [ 4, 5) 134  23.51%  29.82% ###
# [ 5, 5] 400  70.18% 100.00% ##########
#
# Number of training obs by leaf:
# Count: 570 Average: 30.5158 StdDev: 72.0563
# Min: 5 Max: 470 Ignored: 0
# ----------------------------------------------
# [   5,  28) 477  83.68%  83.68% ##########
# [  28,  51)  22   3.86%  87.54%
# [  51,  74)  19   3.33%  90.88%
# [  74,  98)  11   1.93%  92.81%
# [  98, 121)   3   0.53%  93.33%
# [ 121, 144)   6   1.05%  94.39%
# [ 144, 168)   6   1.05%  95.44%
# [ 168, 191)   2   0.35%  95.79%
# [ 191, 214)   2   0.35%  96.14%
# [ 214, 238)   3   0.53%  96.67%
# [ 238, 261)   2   0.35%  97.02%
# [ 261, 284)   1   0.18%  97.19%
# [ 284, 307)   1   0.18%  97.37%
# [ 307, 331)   1   0.18%  97.54%
# [ 331, 354)   0   0.00%  97.54%
# [ 354, 377)   1   0.18%  97.72%
# [ 377, 401)  10   1.75%  99.47%
# [ 401, 424)   0   0.00%  99.47%
# [ 424, 447)   0   0.00%  99.47%
# [ 447, 470]   3   0.53% 100.00%
#
# Attribute in nodes:
# 	86 : Autocorrelation [NUMERICAL]
# 	41 : JointAverage [NUMERICAL]
# 	40 : Correlation [NUMERICAL]
# 	38 : Idm [NUMERICAL]
# 	36 : SumAverage [NUMERICAL]
# 	32 : Imc2 [NUMERICAL]
# 	31 : ClusterShade [NUMERICAL]
# 	28 : DifferenceVariance [NUMERICAL]
# 	28 : DifferenceEntropy [NUMERICAL]
# 	27 : MCC [NUMERICAL]
# 	26 : InverseVariance [NUMERICAL]
# 	22 : MaximumProbability [NUMERICAL]
# 	22 : Imc1 [NUMERICAL]
# 	16 : Id [NUMERICAL]
# 	11 : JointEntropy [NUMERICAL]
# 	10 : SumSquares [NUMERICAL]
# 	10 : Idmn [NUMERICAL]
# 	9 : SumEntropy [NUMERICAL]
# 	9 : ClusterProminence [NUMERICAL]
# 	8 : Idn [NUMERICAL]
# 	5 : ClusterTendency [NUMERICAL]
# 	4 : Contrast [NUMERICAL]
# 	3 : DifferenceAverage [NUMERICAL]
# 	2 : JointEnergy [NUMERICAL]
#
# Attribute in nodes with depth <= 0:
# 	26 : Autocorrelation [NUMERICAL]
#
# Attribute in nodes with depth <= 1:
# 	29 : Autocorrelation [NUMERICAL]
# 	23 : Correlation [NUMERICAL]
# 	7 : Imc2 [NUMERICAL]
# 	4 : SumAverage [NUMERICAL]
# 	4 : Imc1 [NUMERICAL]
# 	4 : DifferenceVariance [NUMERICAL]
# 	3 : JointAverage [NUMERICAL]
# 	1 : SumSquares [NUMERICAL]
# 	1 : MCC [NUMERICAL]
# 	1 : Idm [NUMERICAL]
# 	1 : ClusterTendency [NUMERICAL]
#
# Attribute in nodes with depth <= 2:
# 	35 : Autocorrelation [NUMERICAL]
# 	23 : Correlation [NUMERICAL]
# 	18 : Idm [NUMERICAL]
# 	16 : DifferenceVariance [NUMERICAL]
# 	13 : DifferenceEntropy [NUMERICAL]
# 	12 : SumAverage [NUMERICAL]
# 	12 : InverseVariance [NUMERICAL]
# 	12 : Imc2 [NUMERICAL]
# 	9 : JointAverage [NUMERICAL]
# 	6 : ClusterShade [NUMERICAL]
# 	5 : Id [NUMERICAL]
# 	4 : Imc1 [NUMERICAL]
# 	3 : MaximumProbability [NUMERICAL]
# 	2 : MCC [NUMERICAL]
# 	2 : Contrast [NUMERICAL]
# 	2 : ClusterProminence [NUMERICAL]
# 	1 : SumSquares [NUMERICAL]
# 	1 : Idn [NUMERICAL]
# 	1 : ClusterTendency [NUMERICAL]
#
# Attribute in nodes with depth <= 3:
# 	62 : Autocorrelation [NUMERICAL]
# 	27 : JointAverage [NUMERICAL]
# 	26 : Correlation [NUMERICAL]
# 	25 : Imc2 [NUMERICAL]
# 	24 : Idm [NUMERICAL]
# 	23 : SumAverage [NUMERICAL]
# 	20 : InverseVariance [NUMERICAL]
# 	20 : DifferenceVariance [NUMERICAL]
# 	20 : DifferenceEntropy [NUMERICAL]
# 	16 : ClusterShade [NUMERICAL]
# 	15 : MCC [NUMERICAL]
# 	14 : Imc1 [NUMERICAL]
# 	13 : MaximumProbability [NUMERICAL]
# 	11 : Id [NUMERICAL]
# 	5 : SumEntropy [NUMERICAL]
# 	5 : JointEntropy [NUMERICAL]
# 	4 : Contrast [NUMERICAL]
# 	3 : Idn [NUMERICAL]
# 	3 : Idmn [NUMERICAL]
# 	2 : SumSquares [NUMERICAL]
# 	2 : DifferenceAverage [NUMERICAL]
# 	2 : ClusterTendency [NUMERICAL]
# 	2 : ClusterProminence [NUMERICAL]
#
# Attribute in nodes with depth <= 5:
# 	86 : Autocorrelation [NUMERICAL]
# 	41 : JointAverage [NUMERICAL]
# 	40 : Correlation [NUMERICAL]
# 	38 : Idm [NUMERICAL]
# 	36 : SumAverage [NUMERICAL]
# 	32 : Imc2 [NUMERICAL]
# 	31 : ClusterShade [NUMERICAL]
# 	28 : DifferenceVariance [NUMERICAL]
# 	28 : DifferenceEntropy [NUMERICAL]
# 	27 : MCC [NUMERICAL]
# 	26 : InverseVariance [NUMERICAL]
# 	22 : MaximumProbability [NUMERICAL]
# 	22 : Imc1 [NUMERICAL]
# 	16 : Id [NUMERICAL]
# 	11 : JointEntropy [NUMERICAL]
# 	10 : SumSquares [NUMERICAL]
# 	10 : Idmn [NUMERICAL]
# 	9 : SumEntropy [NUMERICAL]
# 	9 : ClusterProminence [NUMERICAL]
# 	8 : Idn [NUMERICAL]
# 	5 : ClusterTendency [NUMERICAL]
# 	4 : Contrast [NUMERICAL]
# 	3 : DifferenceAverage [NUMERICAL]
# 	2 : JointEnergy [NUMERICAL]
#
# Condition type in nodes:
# 	544 : HigherCondition
# Condition type in nodes with depth <= 0:
# 	26 : HigherCondition
# Condition type in nodes with depth <= 1:
# 	78 : HigherCondition
# Condition type in nodes with depth <= 2:
# 	177 : HigherCondition
# Condition type in nodes with depth <= 3:
# 	344 : HigherCondition
# Condition type in nodes with depth <= 5:
# 	544 : HigherCondition
#
# Training logs:
# Number of iteration to final model: 26
# 	Iter:1 train-loss:1.215387 valid-loss:1.227757  train-accuracy:0.966139 valid-accuracy:0.954830
# 	Iter:2 train-loss:1.075539 valid-loss:1.095457  train-accuracy:0.966986 valid-accuracy:0.954830
# 	Iter:3 train-loss:0.958788 valid-loss:1.038358  train-accuracy:0.970372 valid-accuracy:0.890698
# 	Iter:4 train-loss:0.853343 valid-loss:0.951091  train-accuracy:0.982223 valid-accuracy:0.908766
# 	Iter:5 train-loss:0.767350 valid-loss:0.857437  train-accuracy:0.985609 valid-accuracy:0.899732
# 	Iter:6 train-loss:0.692693 valid-loss:0.799510  train-accuracy:0.983070 valid-accuracy:0.899732
# 	Iter:16 train-loss:0.276443 valid-loss:0.542250  train-accuracy:0.989842 valid-accuracy:0.908766
# 	Iter:26 train-loss:0.134140 valid-loss:0.477005  train-accuracy:0.995767 valid-accuracy:0.908766
# 	Iter:36 train-loss:0.071831 valid-loss:0.520926  train-accuracy:0.997460 valid-accuracy:0.908766
# 	Iter:46 train-loss:0.042201 valid-loss:0.556058  train-accuracy:0.999153 valid-accuracy:0.917800
# 	Iter:56 train-loss:0.025223 valid-loss:0.596903  train-accuracy:1.000000 valid-accuracy:0.917800

# %%
# Model features
model.make_inspector().features()
# Out:
# ["Autocorrelation" (1; #0),
#  "ClusterProminence" (1; #1),
#  "ClusterShade" (1; #2),
#  "ClusterTendency" (1; #3),
#  "Contrast" (1; #4),
#  "Correlation" (1; #5),
#  "DifferenceAverage" (1; #6),
#  "DifferenceEntropy" (1; #7),
#  "DifferenceVariance" (1; #8),
#  "Id" (1; #9),
#  "Idm" (1; #10),
#  "Idmn" (1; #11),
#  "Idn" (1; #12),
#  "Imc1" (1; #13),
#  "Imc2" (1; #14),
#  "InverseVariance" (1; #15),
#  "JointAverage" (1; #16),
#  "JointEnergy" (1; #17),
#  "JointEntropy" (1; #18),
#  "MCC" (1; #19),
#  "MaximumProbability" (1; #20),
#  "SumAverage" (1; #21),
#  "SumEntropy" (1; #22),
#  "SumSquares" (1; #23)]

# %%
# Feature importance
model.make_inspector().variable_importances()
# Out:
# {'INV_MEAN_MIN_DEPTH': [("Autocorrelation" (1; #0), 1.0),
#   ("Correlation" (1; #5), 0.2532114994219395),
#   ("DifferenceVariance" (1; #8), 0.20555298388122584),
#   ("Idm" (1; #10), 0.20423127474817468),
#   ("Imc2" (1; #14), 0.20416877255801827),
#   ("JointAverage" (1; #16), 0.2024933245029431),
#   ("SumAverage" (1; #21), 0.20084138260173778),
#   ("DifferenceEntropy" (1; #7), 0.1921071152223471),
#   ("Imc1" (1; #13), 0.19032734267723153),
#   ("InverseVariance" (1; #15), 0.18828464087984312),
#   ("ClusterShade" (1; #2), 0.1870917017789622),
#   ("MCC" (1; #19), 0.18592961706263553),
#   ("MaximumProbability" (1; #20), 0.18533976259517895),
#   ("Id" (1; #9), 0.18467576648871076),
#   ("SumSquares" (1; #23), 0.18148221028461295),
#   ("ClusterTendency" (1; #3), 0.1808005360903423),
#   ("Idn" (1; #12), 0.180433373250671),
#   ("SumEntropy" (1; #22), 0.18033347668395405),
#   ("JointEntropy" (1; #18), 0.18008255346315594),
#   ("Contrast" (1; #4), 0.1799271973670896),
#   ("ClusterProminence" (1; #1), 0.17974676846322837),
#   ("Idmn" (1; #11), 0.17954336717822428),
#   ("DifferenceAverage" (1; #6), 0.17860296524307842),
#   ("JointEnergy" (1; #17), 0.1783477293992077)],
#  'SUM_SCORE': [("Autocorrelation" (1; #0), 628.5066772695071),
#   ("Correlation" (1; #5), 32.270352254872776),
#   ("SumAverage" (1; #21), 28.582023772062968),
#   ("JointAverage" (1; #16), 26.402749370434712),
#   ("Idm" (1; #10), 20.17765904725701),
#   ("DifferenceEntropy" (1; #7), 18.89401342584442),
#   ("MaximumProbability" (1; #20), 17.56887428211424),
#   ("DifferenceVariance" (1; #8), 16.14210230983762),
#   ("InverseVariance" (1; #15), 15.752343880511923),
#   ("Id" (1; #9), 14.690062650944059),
#   ("Imc1" (1; #13), 13.807851766324903),
#   ("Imc2" (1; #14), 10.352153924783664),
#   ("MCC" (1; #19), 7.753803343258286),
#   ("ClusterShade" (1; #2), 7.704263537845321),
#   ("JointEntropy" (1; #18), 6.491386597634122),
#   ("DifferenceAverage" (1; #6), 2.937865898210296),
#   ("SumEntropy" (1; #22), 1.8587148955834043),
#   ("Idn" (1; #12), 1.5304594579898116),
#   ("SumSquares" (1; #23), 1.3857955605625079),
#   ("ClusterTendency" (1; #3), 1.312621294050074),
#   ("JointEnergy" (1; #17), 0.5667737550737043),
#   ("Idmn" (1; #11), 0.5070985045259634),
#   ("Contrast" (1; #4), 0.4002611681783339),
#   ("ClusterProminence" (1; #1), 0.2926871969371265)],
#  'NUM_AS_ROOT': [("Autocorrelation" (1; #0), 26.0)],
#  'NUM_NODES': [("Autocorrelation" (1; #0), 86.0),
#   ("JointAverage" (1; #16), 41.0),
#   ("Correlation" (1; #5), 40.0),
#   ("Idm" (1; #10), 38.0),
#   ("SumAverage" (1; #21), 36.0),
#   ("Imc2" (1; #14), 32.0),
#   ("ClusterShade" (1; #2), 31.0),
#   ("DifferenceEntropy" (1; #7), 28.0),
#   ("DifferenceVariance" (1; #8), 28.0),
#   ("MCC" (1; #19), 27.0),
#   ("InverseVariance" (1; #15), 26.0),
#   ("Imc1" (1; #13), 22.0),
#   ("MaximumProbability" (1; #20), 22.0),
#   ("Id" (1; #9), 16.0),
#   ("JointEntropy" (1; #18), 11.0),
#   ("Idmn" (1; #11), 10.0),
#   ("SumSquares" (1; #23), 10.0),
#   ("ClusterProminence" (1; #1), 9.0),
#   ("SumEntropy" (1; #22), 9.0),
#   ("Idn" (1; #12), 8.0),
#   ("ClusterTendency" (1; #3), 5.0),
#   ("Contrast" (1; #4), 4.0),
#   ("DifferenceAverage" (1; #6), 3.0),
#   ("JointEnergy" (1; #17), 2.0)]}

# %%
# Model self evaluation
model.make_inspector().evaluation()
# Out:
# Evaluation(num_examples=None, accuracy=0.9087660312652588, loss=0.4770051836967468, rmse=None, ndcg=None, aucs=None, auuc=None, qini=None)

# %%
logs = model.make_inspector().training_logs()

plt.figure(figsize=(12, 4))
plt.subplot(1, 2, 1)
plt.plot([log.num_trees for log in logs], [log.evaluation.accuracy for log in logs])
plt.xlabel("Number of trees")
plt.ylabel("Accuracy (out-of-bag)")
plt.subplot(1, 2, 2)
plt.plot([log.num_trees for log in logs], [log.evaluation.loss for log in logs])
plt.xlabel("Number of trees")
plt.ylabel("Logloss (out-of-bag)")
plt.show()

# %% [markdown]
# Calculate the score of our hold-out validation dataset

# %%
predictions = model.predict(val_ds)
y_true      = validation_data["label"]

from sklearn.metrics import roc_auc_score
ROC_AUC = roc_auc_score(y_true, predictions)
print("The ROC AUC score is %.5f" % ROC_AUC )
# Out:
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 73ms/step
# The ROC AUC score is 0.98509

# %%
# Compute binary classification metrics with sklearn
import numpy as np
from sklearn.metrics import (
    accuracy_score,
    precision_score,
    recall_score,
    f1_score,
    roc_auc_score,
    average_precision_score,
    confusion_matrix,
    classification_report,
    matthews_corrcoef,
    log_loss,
    brier_score_loss,
)

# Get predictions (probabilities or class labels)
preds = model.predict(test_ds)
# If model outputs probabilities, convert to labels by threshold 0.5
if preds.ndim == 2:
    # For TFDF classification, preds may be class probabilities with shape (N, 2)
    if preds.shape[1] == 2:
        pos_probs = preds[:, 1]
    else:
        # If single-probability column (positive class)
        pos_probs = preds[:, -1]
    y_pred = (pos_probs >= 0.5).astype(int)
else:
    # Already class labels
    y_pred = preds.astype(int)
    pos_probs = None

# Ground truth labels (must be 0/1 integers)
y_true = test_data["label"].astype(int).to_numpy()

# Core metrics
metrics = {}
metrics["accuracy"] = accuracy_score(y_true, y_pred)
metrics["precision"] = precision_score(y_true, y_pred, zero_division=0)
metrics["recall"] = recall_score(y_true, y_pred, zero_division=0)
metrics["f1"] = f1_score(y_true, y_pred, zero_division=0)
metrics["mcc"] = matthews_corrcoef(y_true, y_pred)

# Probabilistic metrics (only if we have probabilities)
if pos_probs is not None:
    metrics["roc_auc"] = roc_auc_score(y_true, pos_probs)
    metrics["pr_auc"] = average_precision_score(y_true, pos_probs)
    metrics["log_loss"] = log_loss(y_true, pos_probs, labels=[0,1])
    metrics["brier_score"] = brier_score_loss(y_true, pos_probs)

# Confusion matrix and detailed report
cm = confusion_matrix(y_true, y_pred, labels=[0,1])
report = classification_report(y_true, y_pred, digits=4)

print("Sklearn binary metrics:")
for k, v in metrics.items():
    print(f"{k}: {v:.4f}")
print("\nConfusion matrix:\n", cm)
print("\nClassification report:\n", report)
# Out:
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 78ms/step
# Sklearn binary metrics:
# accuracy: 0.9387
# precision: 0.7949
# recall: 0.8611
# f1: 0.8267
# mcc: 0.7904
# roc_auc: 0.9776
# pr_auc: 0.9018
# log_loss: 0.1799
# brier_score: 0.0501
#
# Confusion matrix:
#  [[168   8]
#  [  5  31]]
#
# Classification report:
#                precision    recall  f1-score   support
#
#            0     0.9711    0.9545    0.9628       176
#            1     0.7949    0.8611    0.8267        36
#
#     accuracy                         0.9387       212
#    macro avg     0.8830    0.9078    0.8947       212
# weighted avg     0.9412    0.9387    0.9396       212
