# %%
# Import packages and modules
import numpy  as np
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow_decision_forests as tfdf

from sklearn.model_selection import train_test_split
# Out:
# 2026-08-13 04:14:29.239058: I tensorflow/core/util/port.cc:113] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2026-08-13 04:14:29.633784: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2026-08-13 04:14:34.338788: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
# Check the version of TensorFlow Decision Forests
print("Found TensorFlow Decision Forests v" + tfdf.__version__)
# Out:
# Found TensorFlow Decision Forests v1.9.1

# %%
datasetPath = 'dataset/firstorder/kernel5/dataset.csv'

# %%
# Parameters
datasetPath = "dataset/firstorder/kernel5/1.dataset.csv"

# %%
# train/validation/test = 70/10/20
dataset = pd.read_csv(datasetPath)

train_data, temp_data = train_test_split(dataset, test_size=0.3, random_state=42)
validation_data, test_data = train_test_split(temp_data, test_size=2/3, random_state=42)

# %%
from sklearn.utils.class_weight import compute_class_weight

# tinh class weight tren tap train
classes = np.array([0, 1])
weights = compute_class_weight(class_weight="balanced", classes=classes, y=train_data["label"])
class_weight = {0: weights[0], 1: weights[1]}

# gan sample_weight cho tung dong
train_data["sample_weight"] = train_data["label"].map(class_weight)
validation_data["sample_weight"] = validation_data["label"].map(class_weight)
test_data["sample_weight"] = test_data["label"].map(class_weight)

# Convert the dataset into a TensorFlow dataset.
train_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    train_data, label="label", weight="sample_weight"
)         
val_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    validation_data, label="label", weight="sample_weight"
)
test_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    test_data, label="label", weight="sample_weight"
)
# Out:
# 2026-08-13 04:14:47.213920: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:984] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2026-08-13 04:14:47.215195: W tensorflow/core/common_runtime/gpu/gpu_device.cc:2251] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...

# %%
import keras

# %%
# %%time

# Train a Gradient Boosted Trees model.
model = tfdf.keras.GradientBoostedTreesModel()

# Add evaluation metrics
model.compile(
    metrics=["accuracy"]
)
model.fit(x=train_ds)

# # Train a Gradient Boosted Trees model.
# model = tfdf.keras.GradientBoostedTreesModel(num_trees=1500)
# model.fit(train_ds)
# Out:
# Use /tmp/tmpo2o0m6hr as temporary training directory
# Reading training dataset...
# [WARNING 26-08-13 04:14:47.3808 UTC gradient_boosted_trees.cc:1840] "goss_alpha" set but "sampling_method" not equal to "GOSS".
# [WARNING 26-08-13 04:14:47.3811 UTC gradient_boosted_trees.cc:1851] "goss_beta" set but "sampling_method" not equal to "GOSS".
# [WARNING 26-08-13 04:14:47.3811 UTC gradient_boosted_trees.cc:1865] "selective_gradient_boosting_ratio" set but "sampling_method" not equal to "SELGB".
# Training dataset read in 0:00:02.667176. Found 737 examples.
# Training model...
# Model trained in 0:00:00.378676
# Compiling model...
# [INFO 26-08-13 04:14:50.4559 UTC kernel.cc:1233] Loading model from path /tmp/tmpo2o0m6hr/model/ with prefix ec1a877b58384d61
# [INFO 26-08-13 04:14:50.4589 UTC quick_scorer_extended.cc:911] The binary was compiled without AVX2 support, but your CPU supports it. Enable it for faster model inference.
# [INFO 26-08-13 04:14:50.4590 UTC abstract_model.cc:1362] Engine "GradientBoostedTreesQuickScorerExtended" built
# [INFO 26-08-13 04:14:50.4591 UTC kernel.cc:1061] Use fast generic engine
# Model compiled.
# CPU times: user 5.81 s, sys: 685 ms, total: 6.49 s
# Wall time: 8.12 s

# %%
# Evaluate the model
evaluate = model.evaluate(val_ds, return_dict=True)
print()

for name, value in evaluate.items():
    print(f"{name}: {value:.4f}")
# Out:
# WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 1/1 [==============================] - ETA: 0s - loss: 0.0000e+00 - accuracy: 0.9048
# 1/1 [==============================] - 3s 3s/step - loss: 0.0000e+00 - accuracy: 0.9048
# loss: 0.0000
# accuracy: 0.9048

# %%
# Model Summary
model.summary()
# Out:
# Model: "gradient_boosted_trees_model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
# =================================================================
# Total params: 1 (1.00 Byte)
# Trainable params: 0 (0.00 Byte)
# Non-trainable params: 1 (1.00 Byte)
# _________________________________________________________________
# Type: "GRADIENT_BOOSTED_TREES"
# Task: CLASSIFICATION
# Label: "__LABEL"
#
# Input Features (18):
# 	10Percentile
# 	90Percentile
# 	Energy
# 	Entropy
# 	InterquartileRange
# 	Kurtosis
# 	Maximum
# 	Mean
# 	MeanAbsoluteDeviation
# 	Median
# 	Minimum
# 	Range
# 	RobustMeanAbsoluteDeviation
# 	RootMeanSquared
# 	Skewness
# 	TotalEnergy
# 	Uniformity
# 	Variance
#
# Trained with weights
#
# Variable Importance: INV_MEAN_MIN_DEPTH:
#     1.                      "Median"  0.358682 ################
#     2.                "10Percentile"  0.226466 ###
#     3.                     "Minimum"  0.225307 ###
#     4.                     "Maximum"  0.222931 ###
#     5.                 "TotalEnergy"  0.222216 ###
#     6.                       "Range"  0.209526 #
#     7.             "RootMeanSquared"  0.207147 #
#     8.                      "Energy"  0.204579 #
#     9.                    "Skewness"  0.204016 #
#    10.                     "Entropy"  0.202008 #
#    11.                        "Mean"  0.201375 #
#    12.                  "Uniformity"  0.197085
#    13.          "InterquartileRange"  0.196424
#    14.                    "Kurtosis"  0.195922
#    15. "RobustMeanAbsoluteDeviation"  0.193765
#    16.                    "Variance"  0.192773
#    17.       "MeanAbsoluteDeviation"  0.190867
#    18.                "90Percentile"  0.189210
#
# Variable Importance: NUM_AS_ROOT:
#     1.          "Median" 28.000000 ################
#     2.     "TotalEnergy" 11.000000 #####
#     3.         "Minimum"  7.000000 ###
#     4.    "10Percentile"  5.000000 ##
#     5. "RootMeanSquared"  5.000000 ##
#     6.          "Energy"  4.000000 #
#     7.            "Mean"  3.000000 #
#     8.         "Maximum"  2.000000
#     9.        "Skewness"  2.000000
#    10.           "Range"  1.000000
#
# Variable Importance: NUM_NODES:
#     1.                      "Median" 184.000000 ################
#     2.                "10Percentile" 90.000000 ######
#     3.                     "Minimum" 88.000000 ######
#     4.                       "Range" 88.000000 ######
#     5.                     "Maximum" 71.000000 ####
#     6.                     "Entropy" 59.000000 ###
#     7.                    "Kurtosis" 58.000000 ###
#     8.                        "Mean" 51.000000 ###
#     9.                  "Uniformity" 51.000000 ###
#    10.                    "Skewness" 46.000000 ##
#    11.                    "Variance" 43.000000 ##
#    12.                 "TotalEnergy" 35.000000 #
#    13. "RobustMeanAbsoluteDeviation" 32.000000 #
#    14.             "RootMeanSquared" 32.000000 #
#    15.                      "Energy" 29.000000
#    16.          "InterquartileRange" 28.000000
#    17.       "MeanAbsoluteDeviation" 21.000000
#    18.                "90Percentile" 20.000000
#
# Variable Importance: SUM_SCORE:
#     1.                      "Median" 501.334082 ################
#     2.             "RootMeanSquared" 86.014296 ##
#     3.                 "TotalEnergy" 43.329378 #
#     4.                "10Percentile" 38.752804 #
#     5.                        "Mean" 28.861698
#     6.                     "Maximum" 27.693667
#     7.                    "Kurtosis" 23.176087
#     8.                     "Minimum" 21.064093
#     9.                    "Variance" 20.606017
#    10.                       "Range" 18.190387
#    11. "RobustMeanAbsoluteDeviation" 16.271277
#    12.                      "Energy" 16.144581
#    13.                     "Entropy" 13.593929
#    14.                  "Uniformity" 12.033826
#    15.          "InterquartileRange" 11.312340
#    16.                    "Skewness" 10.077612
#    17.       "MeanAbsoluteDeviation"  2.936442
#    18.                "90Percentile"  1.297100
#
#
#
# Loss: BINOMIAL_LOG_LIKELIHOOD
# Validation loss value: 0.130195
# Number of trees per iteration: 1
# Node format: NOT_SET
# Number of trees: 68
# Total number of nodes: 2120
#
# Number of nodes by tree:
# Count: 68 Average: 31.1765 StdDev: 7.24963
# Min: 19 Max: 49 Ignored: 0
# ----------------------------------------------
# [ 19, 20)  1   1.47%   1.47% #
# [ 20, 22)  4   5.88%   7.35% ###
# [ 22, 23)  0   0.00%   7.35%
# [ 23, 25)  7  10.29%  17.65% #####
# [ 25, 26)  4   5.88%  23.53% ###
# [ 26, 28) 13  19.12%  42.65% ##########
# [ 28, 29)  0   0.00%  42.65%
# [ 29, 31)  4   5.88%  48.53% ###
# [ 31, 32)  7  10.29%  58.82% #####
# [ 32, 34)  8  11.76%  70.59% ######
# [ 34, 36)  5   7.35%  77.94% ####
# [ 36, 37)  0   0.00%  77.94%
# [ 37, 39)  4   5.88%  83.82% ###
# [ 39, 40)  1   1.47%  85.29% #
# [ 40, 42)  1   1.47%  86.76% #
# [ 42, 43)  0   0.00%  86.76%
# [ 43, 45)  3   4.41%  91.18% ##
# [ 45, 46)  4   5.88%  97.06% ###
# [ 46, 48)  1   1.47%  98.53% #
# [ 48, 49]  1   1.47% 100.00% #
#
# Depth by leafs:
# Count: 1094 Average: 4.39854 StdDev: 0.924102
# Min: 1 Max: 5 Ignored: 0
# ----------------------------------------------
# [ 1, 2)   3   0.27%   0.27%
# [ 2, 3)  73   6.67%   6.95% #
# [ 3, 4)  99   9.05%  16.00% #
# [ 4, 5) 229  20.93%  36.93% ###
# [ 5, 5] 690  63.07% 100.00% ##########
#
# Number of training obs by leaf:
# Count: 1094 Average: 41.5832 StdDev: 101.353
# Min: 5 Max: 571 Ignored: 0
# ----------------------------------------------
# [   5,  33) 906  82.82%  82.82% ##########
# [  33,  61)  68   6.22%  89.03% #
# [  61,  90)  21   1.92%  90.95%
# [  90, 118)  19   1.74%  92.69%
# [ 118, 146)   5   0.46%  93.14%
# [ 146, 175)   4   0.37%  93.51%
# [ 175, 203)   1   0.09%  93.60%
# [ 203, 231)   0   0.00%  93.60%
# [ 231, 260)   1   0.09%  93.69%
# [ 260, 288)   7   0.64%  94.33%
# [ 288, 316)   5   0.46%  94.79%
# [ 316, 345)   3   0.27%  95.06%
# [ 345, 373)   3   0.27%  95.34%
# [ 373, 401)  11   1.01%  96.34%
# [ 401, 430)  18   1.65%  97.99%
# [ 430, 458)   5   0.46%  98.45%
# [ 458, 486)   2   0.18%  98.63%
# [ 486, 515)   5   0.46%  99.09%
# [ 515, 543)   4   0.37%  99.45%
# [ 543, 571]   6   0.55% 100.00%
#
# Attribute in nodes:
# 	184 : Median [NUMERICAL]
# 	90 : 10Percentile [NUMERICAL]
# 	88 : Range [NUMERICAL]
# 	88 : Minimum [NUMERICAL]
# 	71 : Maximum [NUMERICAL]
# 	59 : Entropy [NUMERICAL]
# 	58 : Kurtosis [NUMERICAL]
# 	51 : Uniformity [NUMERICAL]
# 	51 : Mean [NUMERICAL]
# 	46 : Skewness [NUMERICAL]
# 	43 : Variance [NUMERICAL]
# 	35 : TotalEnergy [NUMERICAL]
# 	32 : RootMeanSquared [NUMERICAL]
# 	32 : RobustMeanAbsoluteDeviation [NUMERICAL]
# 	29 : Energy [NUMERICAL]
# 	28 : InterquartileRange [NUMERICAL]
# 	21 : MeanAbsoluteDeviation [NUMERICAL]
# 	20 : 90Percentile [NUMERICAL]
#
# Attribute in nodes with depth <= 0:
# 	28 : Median [NUMERICAL]
# 	11 : TotalEnergy [NUMERICAL]
# 	7 : Minimum [NUMERICAL]
# 	5 : RootMeanSquared [NUMERICAL]
# 	5 : 10Percentile [NUMERICAL]
# 	4 : Energy [NUMERICAL]
# 	3 : Mean [NUMERICAL]
# 	2 : Skewness [NUMERICAL]
# 	2 : Maximum [NUMERICAL]
# 	1 : Range [NUMERICAL]
#
# Attribute in nodes with depth <= 1:
# 	63 : Median [NUMERICAL]
# 	26 : Maximum [NUMERICAL]
# 	25 : 10Percentile [NUMERICAL]
# 	17 : Minimum [NUMERICAL]
# 	15 : TotalEnergy [NUMERICAL]
# 	12 : Range [NUMERICAL]
# 	11 : Skewness [NUMERICAL]
# 	11 : Energy [NUMERICAL]
# 	8 : RootMeanSquared [NUMERICAL]
# 	4 : Entropy [NUMERICAL]
# 	3 : Mean [NUMERICAL]
# 	2 : InterquartileRange [NUMERICAL]
# 	1 : RobustMeanAbsoluteDeviation [NUMERICAL]
# 	1 : MeanAbsoluteDeviation [NUMERICAL]
# 	1 : Kurtosis [NUMERICAL]
# 	1 : 90Percentile [NUMERICAL]
#
# Attribute in nodes with depth <= 2:
# 	90 : Median [NUMERICAL]
# 	42 : Minimum [NUMERICAL]
# 	41 : 10Percentile [NUMERICAL]
# 	33 : Maximum [NUMERICAL]
# 	25 : Range [NUMERICAL]
# 	23 : TotalEnergy [NUMERICAL]
# 	21 : Skewness [NUMERICAL]
# 	16 : Energy [NUMERICAL]
# 	15 : RootMeanSquared [NUMERICAL]
# 	14 : Mean [NUMERICAL]
# 	14 : Entropy [NUMERICAL]
# 	13 : Uniformity [NUMERICAL]
# 	13 : Kurtosis [NUMERICAL]
# 	10 : InterquartileRange [NUMERICAL]
# 	9 : RobustMeanAbsoluteDeviation [NUMERICAL]
# 	7 : Variance [NUMERICAL]
# 	4 : MeanAbsoluteDeviation [NUMERICAL]
# 	4 : 90Percentile [NUMERICAL]
#
# Attribute in nodes with depth <= 3:
# 	134 : Median [NUMERICAL]
# 	66 : 10Percentile [NUMERICAL]
# 	63 : Minimum [NUMERICAL]
# 	57 : Range [NUMERICAL]
# 	44 : Maximum [NUMERICAL]
# 	39 : Kurtosis [NUMERICAL]
# 	34 : Skewness [NUMERICAL]
# 	31 : Entropy [NUMERICAL]
# 	30 : Uniformity [NUMERICAL]
# 	28 : Mean [NUMERICAL]
# 	27 : TotalEnergy [NUMERICAL]
# 	23 : RobustMeanAbsoluteDeviation [NUMERICAL]
# 	23 : Energy [NUMERICAL]
# 	21 : Variance [NUMERICAL]
# 	20 : RootMeanSquared [NUMERICAL]
# 	18 : InterquartileRange [NUMERICAL]
# 	12 : MeanAbsoluteDeviation [NUMERICAL]
# 	11 : 90Percentile [NUMERICAL]
#
# Attribute in nodes with depth <= 5:
# 	184 : Median [NUMERICAL]
# 	90 : 10Percentile [NUMERICAL]
# 	88 : Range [NUMERICAL]
# 	88 : Minimum [NUMERICAL]
# 	71 : Maximum [NUMERICAL]
# 	59 : Entropy [NUMERICAL]
# 	58 : Kurtosis [NUMERICAL]
# 	51 : Uniformity [NUMERICAL]
# 	51 : Mean [NUMERICAL]
# 	46 : Skewness [NUMERICAL]
# 	43 : Variance [NUMERICAL]
# 	35 : TotalEnergy [NUMERICAL]
# 	32 : RootMeanSquared [NUMERICAL]
# 	32 : RobustMeanAbsoluteDeviation [NUMERICAL]
# 	29 : Energy [NUMERICAL]
# 	28 : InterquartileRange [NUMERICAL]
# 	21 : MeanAbsoluteDeviation [NUMERICAL]
# 	20 : 90Percentile [NUMERICAL]
#
# Condition type in nodes:
# 	1026 : HigherCondition
# Condition type in nodes with depth <= 0:
# 	68 : HigherCondition
# Condition type in nodes with depth <= 1:
# 	201 : HigherCondition
# Condition type in nodes with depth <= 2:
# 	394 : HigherCondition
# Condition type in nodes with depth <= 3:
# 	681 : HigherCondition
# Condition type in nodes with depth <= 5:
# 	1026 : HigherCondition
#
# Training logs:
# Number of iteration to final model: 68
# 	Iter:1 train-loss:1.220317 valid-loss:1.217435  train-accuracy:0.953681 valid-accuracy:0.946507
# 	Iter:2 train-loss:1.080292 valid-loss:1.083361  train-accuracy:0.975983 valid-accuracy:0.946507
# 	Iter:3 train-loss:0.965974 valid-loss:0.967105  train-accuracy:0.977698 valid-accuracy:0.946507
# 	Iter:4 train-loss:0.864281 valid-loss:0.875204  train-accuracy:0.983703 valid-accuracy:0.955422
# 	Iter:5 train-loss:0.778533 valid-loss:0.792034  train-accuracy:0.981987 valid-accuracy:0.955422
# 	Iter:6 train-loss:0.703132 valid-loss:0.720401  train-accuracy:0.980272 valid-accuracy:0.946507
# 	Iter:16 train-loss:0.303208 valid-loss:0.355786  train-accuracy:0.993138 valid-accuracy:0.964338
# 	Iter:26 train-loss:0.170219 valid-loss:0.239780  train-accuracy:0.992280 valid-accuracy:0.982169
# 	Iter:36 train-loss:0.104094 valid-loss:0.187357  train-accuracy:0.996569 valid-accuracy:0.982169
# 	Iter:46 train-loss:0.073517 valid-loss:0.150093  train-accuracy:0.998285 valid-accuracy:0.982169
# 	Iter:56 train-loss:0.054798 valid-loss:0.139406  train-accuracy:1.000000 valid-accuracy:0.982169
# 	Iter:66 train-loss:0.039547 valid-loss:0.132901  train-accuracy:1.000000 valid-accuracy:0.982169
# 	Iter:76 train-loss:0.029852 valid-loss:0.137187  train-accuracy:1.000000 valid-accuracy:0.982169
# 	Iter:86 train-loss:0.022056 valid-loss:0.152017  train-accuracy:1.000000 valid-accuracy:0.982169
# 	Iter:96 train-loss:0.016393 valid-loss:0.173666  train-accuracy:1.000000 valid-accuracy:0.924036

# %%
# Model features
model.make_inspector().features()
# Out:
# ["10Percentile" (1; #0),
#  "90Percentile" (1; #1),
#  "Energy" (1; #2),
#  "Entropy" (1; #3),
#  "InterquartileRange" (1; #4),
#  "Kurtosis" (1; #5),
#  "Maximum" (1; #6),
#  "Mean" (1; #7),
#  "MeanAbsoluteDeviation" (1; #8),
#  "Median" (1; #9),
#  "Minimum" (1; #10),
#  "Range" (1; #11),
#  "RobustMeanAbsoluteDeviation" (1; #12),
#  "RootMeanSquared" (1; #13),
#  "Skewness" (1; #14),
#  "TotalEnergy" (1; #15),
#  "Uniformity" (1; #16),
#  "Variance" (1; #17)]

# %%
# Feature importance
model.make_inspector().variable_importances()
# Out:
# {'INV_MEAN_MIN_DEPTH': [("Median" (1; #9), 0.3586823710918312),
#   ("10Percentile" (1; #0), 0.22646616353559126),
#   ("Minimum" (1; #10), 0.22530701224071487),
#   ("Maximum" (1; #6), 0.22293084906807548),
#   ("TotalEnergy" (1; #15), 0.22221559971039953),
#   ("Range" (1; #11), 0.20952575408361016),
#   ("RootMeanSquared" (1; #13), 0.2071470326464496),
#   ("Energy" (1; #2), 0.20457877061554097),
#   ("Skewness" (1; #14), 0.20401621043430307),
#   ("Entropy" (1; #3), 0.2020076748639182),
#   ("Mean" (1; #7), 0.20137538171014752),
#   ("Uniformity" (1; #16), 0.1970850242602934),
#   ("InterquartileRange" (1; #4), 0.19642434932496433),
#   ("Kurtosis" (1; #5), 0.19592167959245013),
#   ("RobustMeanAbsoluteDeviation" (1; #12), 0.19376459466573723),
#   ("Variance" (1; #17), 0.1927731044934776),
#   ("MeanAbsoluteDeviation" (1; #8), 0.19086708166551325),
#   ("90Percentile" (1; #1), 0.18920958961801942)],
#  'SUM_SCORE': [("Median" (1; #9), 501.3340822747644),
#   ("RootMeanSquared" (1; #13), 86.01429620699933),
#   ("TotalEnergy" (1; #15), 43.329377518838506),
#   ("10Percentile" (1; #0), 38.752803607939015),
#   ("Mean" (1; #7), 28.86169753500637),
#   ("Maximum" (1; #6), 27.69366669302795),
#   ("Kurtosis" (1; #5), 23.176087073166002),
#   ("Minimum" (1; #10), 21.06409259974391),
#   ("Variance" (1; #17), 20.606017479210088),
#   ("Range" (1; #11), 18.190386957231528),
#   ("RobustMeanAbsoluteDeviation" (1; #12), 16.271276608811725),
#   ("Energy" (1; #2), 16.144581011656282),
#   ("Entropy" (1; #3), 13.593929042197113),
#   ("Uniformity" (1; #16), 12.033826268241643),
#   ("InterquartileRange" (1; #4), 11.312339943483769),
#   ("Skewness" (1; #14), 10.077612010106822),
#   ("MeanAbsoluteDeviation" (1; #8), 2.9364424817314267),
#   ("90Percentile" (1; #1), 1.297099665101301)],
#  'NUM_AS_ROOT': [("Median" (1; #9), 28.0),
#   ("TotalEnergy" (1; #15), 11.0),
#   ("Minimum" (1; #10), 7.0),
#   ("10Percentile" (1; #0), 5.0),
#   ("RootMeanSquared" (1; #13), 5.0),
#   ("Energy" (1; #2), 4.0),
#   ("Mean" (1; #7), 3.0),
#   ("Maximum" (1; #6), 2.0),
#   ("Skewness" (1; #14), 2.0),
#   ("Range" (1; #11), 1.0)],
#  'NUM_NODES': [("Median" (1; #9), 184.0),
#   ("10Percentile" (1; #0), 90.0),
#   ("Minimum" (1; #10), 88.0),
#   ("Range" (1; #11), 88.0),
#   ("Maximum" (1; #6), 71.0),
#   ("Entropy" (1; #3), 59.0),
#   ("Kurtosis" (1; #5), 58.0),
#   ("Mean" (1; #7), 51.0),
#   ("Uniformity" (1; #16), 51.0),
#   ("Skewness" (1; #14), 46.0),
#   ("Variance" (1; #17), 43.0),
#   ("TotalEnergy" (1; #15), 35.0),
#   ("RobustMeanAbsoluteDeviation" (1; #12), 32.0),
#   ("RootMeanSquared" (1; #13), 32.0),
#   ("Energy" (1; #2), 29.0),
#   ("InterquartileRange" (1; #4), 28.0),
#   ("MeanAbsoluteDeviation" (1; #8), 21.0),
#   ("90Percentile" (1; #1), 20.0)]}

# %%
# Model self evaluation
model.make_inspector().evaluation()
# Out:
# Evaluation(num_examples=None, accuracy=0.9821688532829285, loss=0.13019539415836334, rmse=None, ndcg=None, aucs=None, auuc=None, qini=None)

# %%
logs = model.make_inspector().training_logs()

plt.figure(figsize=(12, 4))
plt.subplot(1, 2, 1)
plt.plot([log.num_trees for log in logs], [log.evaluation.accuracy for log in logs])
plt.xlabel("Number of trees")
plt.ylabel("Accuracy (out-of-bag)")
plt.subplot(1, 2, 2)
plt.plot([log.num_trees for log in logs], [log.evaluation.loss for log in logs])
plt.xlabel("Number of trees")
plt.ylabel("Logloss (out-of-bag)")
plt.show()

# %% [markdown]
# Calculate the score of our hold-out validation dataset

# %%
predictions = model.predict(val_ds)
y_true      = validation_data["label"]

from sklearn.metrics import roc_auc_score
ROC_AUC = roc_auc_score(y_true, predictions)
print("The ROC AUC score is %.5f" % ROC_AUC )
# Out:
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 63ms/step
# The ROC AUC score is 0.96505

# %%
# Compute binary classification metrics with sklearn
import numpy as np
from sklearn.metrics import (
    accuracy_score,
    precision_score,
    recall_score,
    f1_score,
    roc_auc_score,
    average_precision_score,
    confusion_matrix,
    classification_report,
    matthews_corrcoef,
    log_loss,
    brier_score_loss,
)

# Get predictions (probabilities or class labels)
preds = model.predict(test_ds)
# If model outputs probabilities, convert to labels by threshold 0.5
if preds.ndim == 2:
    # For TFDF classification, preds may be class probabilities with shape (N, 2)
    if preds.shape[1] == 2:
        pos_probs = preds[:, 1]
    else:
        # If single-probability column (positive class)
        pos_probs = preds[:, -1]
    y_pred = (pos_probs >= 0.5).astype(int)
else:
    # Already class labels
    y_pred = preds.astype(int)
    pos_probs = None

# Ground truth labels (must be 0/1 integers)
y_true = test_data["label"].astype(int).to_numpy()

# Core metrics
metrics = {}
metrics["accuracy"] = accuracy_score(y_true, y_pred)
metrics["precision"] = precision_score(y_true, y_pred, zero_division=0)
metrics["recall"] = recall_score(y_true, y_pred, zero_division=0)
metrics["f1"] = f1_score(y_true, y_pred, zero_division=0)
metrics["mcc"] = matthews_corrcoef(y_true, y_pred)

# Probabilistic metrics (only if we have probabilities)
if pos_probs is not None:
    metrics["roc_auc"] = roc_auc_score(y_true, pos_probs)
    metrics["pr_auc"] = average_precision_score(y_true, pos_probs)
    metrics["log_loss"] = log_loss(y_true, pos_probs, labels=[0,1])
    metrics["brier_score"] = brier_score_loss(y_true, pos_probs)

# Confusion matrix and detailed report
cm = confusion_matrix(y_true, y_pred, labels=[0,1])
report = classification_report(y_true, y_pred, digits=4)

print("Sklearn binary metrics:")
for k, v in metrics.items():
    print(f"{k}: {v:.4f}")
print("\nConfusion matrix:\n", cm)
print("\nClassification report:\n", report)
# Out:
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 65ms/step
# Sklearn binary metrics:
# accuracy: 0.9387
# precision: 0.8214
# recall: 0.7419
# f1: 0.7797
# mcc: 0.7455
# roc_auc: 0.9595
# pr_auc: 0.8807
# log_loss: 0.1609
# brier_score: 0.0464
#
# Confusion matrix:
#  [[176   5]
#  [  8  23]]
#
# Classification report:
#                precision    recall  f1-score   support
#
#            0     0.9565    0.9724    0.9644       181
#            1     0.8214    0.7419    0.7797        31
#
#     accuracy                         0.9387       212
#    macro avg     0.8890    0.8572    0.8720       212
# weighted avg     0.9368    0.9387    0.9374       212
