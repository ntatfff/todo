# %%
# Import packages and modules
import numpy  as np
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow_decision_forests as tfdf

from sklearn.model_selection import train_test_split
# Out:
# 2026-08-13 04:25:48.272137: I tensorflow/core/util/port.cc:113] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2026-08-13 04:25:48.667223: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2026-08-13 04:25:53.718555: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
# Check the version of TensorFlow Decision Forests
print("Found TensorFlow Decision Forests v" + tfdf.__version__)
# Out:
# Found TensorFlow Decision Forests v1.9.1

# %%
datasetPath = 'dataset/firstorder/kernel5/dataset.csv'

# %%
# Parameters
datasetPath = "dataset/firstorder/kernel5/1.dataset.csv"

# %%
# train/validation/test = 70/10/20
dataset = pd.read_csv(datasetPath)

train_data, temp_data = train_test_split(dataset, test_size=0.3, random_state=42)
validation_data, test_data = train_test_split(temp_data, test_size=2/3, random_state=42)

# %%
from sklearn.utils.class_weight import compute_class_weight

# tinh class weight tren tap train
classes = np.array([0, 1])
weights = compute_class_weight(class_weight="balanced", classes=classes, y=train_data["label"])
class_weight = {0: weights[0], 1: weights[1]}

# gan sample_weight cho tung dong
train_data["sample_weight"] = train_data["label"].map(class_weight)
validation_data["sample_weight"] = validation_data["label"].map(class_weight)
test_data["sample_weight"] = test_data["label"].map(class_weight)

# Convert the dataset into a TensorFlow dataset.
train_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    train_data, label="label", weight="sample_weight"
)         
val_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    validation_data, label="label", weight="sample_weight"
)
test_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    test_data, label="label", weight="sample_weight"
)
# Out:
# 2026-08-13 04:26:07.599067: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:984] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2026-08-13 04:26:07.600575: W tensorflow/core/common_runtime/gpu/gpu_device.cc:2251] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...

# %%
import keras

# %%
# %%time

# Train a Random Forest model.
model = tfdf.keras.RandomForestModel()

# Add evaluation metrics
model.compile(
    metrics=["accuracy"]
)
model.fit(x=train_ds)

# # Train a Gradient Boosted Trees model.
# model = tfdf.keras.GradientBoostedTreesModel(num_trees=1500)
# model.fit(train_ds)
# Out:
# Use /tmp/tmp75iz7vjf as temporary training directory
# Reading training dataset...
# Training dataset read in 0:00:02.733527. Found 737 examples.
# Training model...
# Model trained in 0:00:00.066902
# Compiling model...
# [INFO 26-08-13 04:26:10.5750 UTC kernel.cc:1233] Loading model from path /tmp/tmp75iz7vjf/model/ with prefix 71ea1e1cc5b44066
# [INFO 26-08-13 04:26:10.5882 UTC decision_forest.cc:734] Model loaded with 300 root(s), 10744 node(s), and 18 input feature(s).
# [INFO 26-08-13 04:26:10.5882 UTC abstract_model.cc:1362] Engine "RandomForestOptPred" built
# [INFO 26-08-13 04:26:10.5882 UTC kernel.cc:1061] Use fast generic engine
# Model compiled.
# CPU times: user 5.74 s, sys: 74.7 ms, total: 5.81 s
# Wall time: 6.13 s

# %%
# Evaluate the model
evaluate = model.evaluate(val_ds, return_dict=True)
print()

for name, value in evaluate.items():
    print(f"{name}: {value:.4f}")
# Out:
# WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 1/1 [==============================] - ETA: 0s - loss: 0.0000e+00 - accuracy: 0.9238
# 1/1 [==============================] - 3s 3s/step - loss: 0.0000e+00 - accuracy: 0.9238
# loss: 0.0000
# accuracy: 0.9238

# %%
# Model Summary
model.summary()
# Out:
# Model: "random_forest_model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
# =================================================================
# Total params: 1 (1.00 Byte)
# Trainable params: 0 (0.00 Byte)
# Non-trainable params: 1 (1.00 Byte)
# _________________________________________________________________
# Type: "RANDOM_FOREST"
# Task: CLASSIFICATION
# Label: "__LABEL"
#
# Input Features (18):
# 	10Percentile
# 	90Percentile
# 	Energy
# 	Entropy
# 	InterquartileRange
# 	Kurtosis
# 	Maximum
# 	Mean
# 	MeanAbsoluteDeviation
# 	Median
# 	Minimum
# 	Range
# 	RobustMeanAbsoluteDeviation
# 	RootMeanSquared
# 	Skewness
# 	TotalEnergy
# 	Uniformity
# 	Variance
#
# Trained with weights
#
# Variable Importance: INV_MEAN_MIN_DEPTH:
#     1.                      "Median"  0.251606 ################
#     2.                "10Percentile"  0.219765 #########
#     3.                 "TotalEnergy"  0.211389 ########
#     4.             "RootMeanSquared"  0.210469 #######
#     5.                      "Energy"  0.208824 #######
#     6.                        "Mean"  0.194369 ####
#     7.          "InterquartileRange"  0.184952 ##
#     8.                  "Uniformity"  0.183934 ##
#     9. "RobustMeanAbsoluteDeviation"  0.179708 #
#    10.                     "Minimum"  0.176721 #
#    11.                     "Maximum"  0.175828
#    12.                "90Percentile"  0.175537
#    13.                     "Entropy"  0.173610
#    14.                    "Kurtosis"  0.172932
#    15.       "MeanAbsoluteDeviation"  0.172851
#    16.                    "Variance"  0.171251
#    17.                       "Range"  0.171121
#    18.                    "Skewness"  0.171034
#
# Variable Importance: NUM_AS_ROOT:
#     1.          "Median" 75.000000 ################
#     2.          "Energy" 57.000000 ############
#     3. "RootMeanSquared" 56.000000 ###########
#     4.     "TotalEnergy" 56.000000 ###########
#     5.            "Mean" 24.000000 ####
#     6.    "90Percentile" 11.000000 ##
#     7.         "Maximum" 10.000000 #
#     8.    "10Percentile"  9.000000 #
#     9.         "Entropy"  1.000000
#    10.         "Minimum"  1.000000
#
# Variable Importance: NUM_NODES:
#     1.                      "Median" 465.000000 ################
#     2.                "10Percentile" 390.000000 ###########
#     3.                  "Uniformity" 343.000000 ########
#     4.          "InterquartileRange" 325.000000 ######
#     5.                      "Energy" 296.000000 ####
#     6.                        "Mean" 289.000000 ####
#     7.             "RootMeanSquared" 284.000000 ####
#     8.                    "Kurtosis" 282.000000 ####
#     9.                 "TotalEnergy" 278.000000 ###
#    10.                     "Maximum" 276.000000 ###
#    11. "RobustMeanAbsoluteDeviation" 276.000000 ###
#    12.                     "Entropy" 275.000000 ###
#    13.                       "Range" 259.000000 ##
#    14.       "MeanAbsoluteDeviation" 246.000000 #
#    15.                    "Variance" 244.000000 #
#    16.                    "Skewness" 240.000000 #
#    17.                "90Percentile" 233.000000
#    18.                     "Minimum" 221.000000
#
# Variable Importance: SUM_SCORE:
#     1.                      "Median" 28333.784791 ################
#     2.                      "Energy" 20540.821097 ###########
#     3.                 "TotalEnergy" 20274.465782 ###########
#     4.             "RootMeanSquared" 19781.710528 ##########
#     5.                        "Mean" 10042.195053 ####
#     6.                "10Percentile" 8261.017971 ###
#     7.                     "Maximum" 4992.438602 #
#     8.                "90Percentile" 4937.008059 #
#     9.                  "Uniformity" 3515.741473 #
#    10.          "InterquartileRange" 3302.363873
#    11.                     "Entropy" 2753.616587
#    12.                    "Kurtosis" 2636.193974
#    13. "RobustMeanAbsoluteDeviation" 2604.979723
#    14.                     "Minimum" 2570.882232
#    15.                       "Range" 2443.958835
#    16.       "MeanAbsoluteDeviation" 2101.979198
#    17.                    "Variance" 2080.711715
#    18.                    "Skewness" 1853.341681
#
#
#
# Winner takes all: true
# Out-of-bag evaluation: accuracy:0.902718 logloss:0.613803
# Number of trees: 300
# Total number of nodes: 10744
#
# Number of nodes by tree:
# Count: 300 Average: 35.8133 StdDev: 4.54369
# Min: 23 Max: 49 Ignored: 0
# ----------------------------------------------
# [ 23, 24)  1   0.33%   0.33%
# [ 24, 25)  0   0.00%   0.33%
# [ 25, 27)  1   0.33%   0.67%
# [ 27, 28) 10   3.33%   4.00% ##
# [ 28, 29)  0   0.00%   4.00%
# [ 29, 31) 19   6.33%  10.33% ###
# [ 31, 32) 31  10.33%  20.67% #####
# [ 32, 33)  0   0.00%  20.67%
# [ 33, 35) 40  13.33%  34.00% #######
# [ 35, 36) 49  16.33%  50.33% ########
# [ 36, 37)  0   0.00%  50.33%
# [ 37, 39) 59  19.67%  70.00% ##########
# [ 39, 40) 40  13.33%  83.33% #######
# [ 40, 41)  0   0.00%  83.33%
# [ 41, 43) 29   9.67%  93.00% #####
# [ 43, 44)  9   3.00%  96.00% ##
# [ 44, 45)  0   0.00%  96.00%
# [ 45, 47)  6   2.00%  98.00% #
# [ 47, 48)  2   0.67%  98.67%
# [ 48, 49]  4   1.33% 100.00% #
#
# Depth by leafs:
# Count: 5522 Average: 5.32524 StdDev: 2.0491
# Min: 1 Max: 13 Ignored: 0
# ----------------------------------------------
# [  1,  2)    2   0.04%   0.04%
# [  2,  3)  357   6.47%   6.50% ###
# [  3,  4)  742  13.44%  19.94% #######
# [  4,  5) 1021  18.49%  38.43% ##########
# [  5,  6) 1018  18.44%  56.86% ##########
# [  6,  7)  904  16.37%  73.23% #########
# [  7,  8)  641  11.61%  84.84% ######
# [  8,  9)  418   7.57%  92.41% ####
# [  9, 10)  243   4.40%  96.81% ##
# [ 10, 11)  111   2.01%  98.82% #
# [ 11, 12)   44   0.80%  99.62%
# [ 12, 13)   19   0.34%  99.96%
# [ 13, 13]    2   0.04% 100.00%
#
# Number of training obs by leaf:
# Count: 5522 Average: 40.0398 StdDev: 97.1768
# Min: 5 Max: 564 Ignored: 0
# ----------------------------------------------
# [   5,  33) 4441  80.42%  80.42% ##########
# [  33,  61)  512   9.27%  89.70% #
# [  61,  89)  113   2.05%  91.74%
# [  89, 117)   37   0.67%  92.41%
# [ 117, 145)   53   0.96%  93.37%
# [ 145, 173)   42   0.76%  94.13%
# [ 173, 201)   18   0.33%  94.46%
# [ 201, 229)    4   0.07%  94.53%
# [ 229, 257)    2   0.04%  94.57%
# [ 257, 285)    3   0.05%  94.62%
# [ 285, 313)    2   0.04%  94.66%
# [ 313, 341)    8   0.14%  94.80%
# [ 341, 369)   66   1.20%  96.00%
# [ 369, 397)   62   1.12%  97.12%
# [ 397, 425)   23   0.42%  97.54%
# [ 425, 453)   19   0.34%  97.88%
# [ 453, 481)   31   0.56%  98.44%
# [ 481, 509)   41   0.74%  99.19%
# [ 509, 537)   32   0.58%  99.76%
# [ 537, 564]   13   0.24% 100.00%
#
# Attribute in nodes:
# 	465 : Median [NUMERICAL]
# 	390 : 10Percentile [NUMERICAL]
# 	343 : Uniformity [NUMERICAL]
# 	325 : InterquartileRange [NUMERICAL]
# 	296 : Energy [NUMERICAL]
# 	289 : Mean [NUMERICAL]
# 	284 : RootMeanSquared [NUMERICAL]
# 	282 : Kurtosis [NUMERICAL]
# 	278 : TotalEnergy [NUMERICAL]
# 	276 : RobustMeanAbsoluteDeviation [NUMERICAL]
# 	276 : Maximum [NUMERICAL]
# 	275 : Entropy [NUMERICAL]
# 	259 : Range [NUMERICAL]
# 	246 : MeanAbsoluteDeviation [NUMERICAL]
# 	244 : Variance [NUMERICAL]
# 	240 : Skewness [NUMERICAL]
# 	233 : 90Percentile [NUMERICAL]
# 	221 : Minimum [NUMERICAL]
#
# Attribute in nodes with depth <= 0:
# 	75 : Median [NUMERICAL]
# 	57 : Energy [NUMERICAL]
# 	56 : TotalEnergy [NUMERICAL]
# 	56 : RootMeanSquared [NUMERICAL]
# 	24 : Mean [NUMERICAL]
# 	11 : 90Percentile [NUMERICAL]
# 	10 : Maximum [NUMERICAL]
# 	9 : 10Percentile [NUMERICAL]
# 	1 : Minimum [NUMERICAL]
# 	1 : Entropy [NUMERICAL]
#
# Attribute in nodes with depth <= 1:
# 	150 : Median [NUMERICAL]
# 	127 : TotalEnergy [NUMERICAL]
# 	127 : Energy [NUMERICAL]
# 	112 : RootMeanSquared [NUMERICAL]
# 	104 : 10Percentile [NUMERICAL]
# 	85 : Mean [NUMERICAL]
# 	43 : 90Percentile [NUMERICAL]
# 	38 : Maximum [NUMERICAL]
# 	37 : Minimum [NUMERICAL]
# 	24 : Entropy [NUMERICAL]
# 	23 : Range [NUMERICAL]
# 	13 : Uniformity [NUMERICAL]
# 	6 : Variance [NUMERICAL]
# 	4 : MeanAbsoluteDeviation [NUMERICAL]
# 	3 : Skewness [NUMERICAL]
# 	1 : RobustMeanAbsoluteDeviation [NUMERICAL]
# 	1 : Kurtosis [NUMERICAL]
#
# Attribute in nodes with depth <= 2:
# 	224 : Median [NUMERICAL]
# 	179 : 10Percentile [NUMERICAL]
# 	163 : Energy [NUMERICAL]
# 	155 : TotalEnergy [NUMERICAL]
# 	145 : RootMeanSquared [NUMERICAL]
# 	131 : Mean [NUMERICAL]
# 	87 : Uniformity [NUMERICAL]
# 	78 : Minimum [NUMERICAL]
# 	74 : Entropy [NUMERICAL]
# 	67 : RobustMeanAbsoluteDeviation [NUMERICAL]
# 	67 : Range [NUMERICAL]
# 	65 : 90Percentile [NUMERICAL]
# 	63 : Maximum [NUMERICAL]
# 	63 : InterquartileRange [NUMERICAL]
# 	62 : Variance [NUMERICAL]
# 	51 : MeanAbsoluteDeviation [NUMERICAL]
# 	35 : Kurtosis [NUMERICAL]
# 	28 : Skewness [NUMERICAL]
#
# Attribute in nodes with depth <= 3:
# 	295 : Median [NUMERICAL]
# 	250 : 10Percentile [NUMERICAL]
# 	196 : Energy [NUMERICAL]
# 	187 : TotalEnergy [NUMERICAL]
# 	174 : Mean [NUMERICAL]
# 	167 : RootMeanSquared [NUMERICAL]
# 	160 : Uniformity [NUMERICAL]
# 	154 : InterquartileRange [NUMERICAL]
# 	129 : Entropy [NUMERICAL]
# 	123 : RobustMeanAbsoluteDeviation [NUMERICAL]
# 	119 : Maximum [NUMERICAL]
# 	112 : Minimum [NUMERICAL]
# 	110 : Range [NUMERICAL]
# 	109 : Variance [NUMERICAL]
# 	107 : 90Percentile [NUMERICAL]
# 	101 : MeanAbsoluteDeviation [NUMERICAL]
# 	100 : Kurtosis [NUMERICAL]
# 	80 : Skewness [NUMERICAL]
#
# Attribute in nodes with depth <= 5:
# 	403 : Median [NUMERICAL]
# 	334 : 10Percentile [NUMERICAL]
# 	260 : Uniformity [NUMERICAL]
# 	256 : Energy [NUMERICAL]
# 	254 : InterquartileRange [NUMERICAL]
# 	247 : Mean [NUMERICAL]
# 	236 : TotalEnergy [NUMERICAL]
# 	230 : RootMeanSquared [NUMERICAL]
# 	220 : Maximum [NUMERICAL]
# 	215 : RobustMeanAbsoluteDeviation [NUMERICAL]
# 	212 : Kurtosis [NUMERICAL]
# 	205 : Entropy [NUMERICAL]
# 	202 : Range [NUMERICAL]
# 	193 : Variance [NUMERICAL]
# 	192 : MeanAbsoluteDeviation [NUMERICAL]
# 	187 : 90Percentile [NUMERICAL]
# 	182 : Skewness [NUMERICAL]
# 	180 : Minimum [NUMERICAL]
#
# Condition type in nodes:
# 	5222 : HigherCondition
# Condition type in nodes with depth <= 0:
# 	300 : HigherCondition
# Condition type in nodes with depth <= 1:
# 	898 : HigherCondition
# Condition type in nodes with depth <= 2:
# 	1737 : HigherCondition
# Condition type in nodes with depth <= 3:
# 	2673 : HigherCondition
# Condition type in nodes with depth <= 5:
# 	4208 : HigherCondition
# Node format: NOT_SET
#
# Training OOB:
# 	trees: 1, Out-of-bag evaluation: accuracy:0.855152 logloss:5.22085
# 	trees: 13, Out-of-bag evaluation: accuracy:0.87084 logloss:1.97935
# 	trees: 24, Out-of-bag evaluation: accuracy:0.884282 logloss:1.37896
# 	trees: 34, Out-of-bag evaluation: accuracy:0.874078 logloss:1.17371
# 	trees: 44, Out-of-bag evaluation: accuracy:0.87486 logloss:0.979551
# 	trees: 54, Out-of-bag evaluation: accuracy:0.864656 logloss:0.982985
# 	trees: 64, Out-of-bag evaluation: accuracy:0.87486 logloss:0.984716
# 	trees: 74, Out-of-bag evaluation: accuracy:0.871323 logloss:0.981763
# 	trees: 85, Out-of-bag evaluation: accuracy:0.88231 logloss:0.975557
# 	trees: 95, Out-of-bag evaluation: accuracy:0.876425 logloss:0.970138
# 	trees: 105, Out-of-bag evaluation: accuracy:0.893296 logloss:0.969096
# 	trees: 115, Out-of-bag evaluation: accuracy:0.90782 logloss:0.943233
# 	trees: 125, Out-of-bag evaluation: accuracy:0.907037 logloss:0.94189
# 	trees: 135, Out-of-bag evaluation: accuracy:0.897616 logloss:0.94207
# 	trees: 145, Out-of-bag evaluation: accuracy:0.897616 logloss:0.940537
# 	trees: 155, Out-of-bag evaluation: accuracy:0.90782 logloss:0.936079
# 	trees: 165, Out-of-bag evaluation: accuracy:0.908602 logloss:0.772627
# 	trees: 175, Out-of-bag evaluation: accuracy:0.904283 logloss:0.773453
# 	trees: 185, Out-of-bag evaluation: accuracy:0.9035 logloss:0.772067
# 	trees: 195, Out-of-bag evaluation: accuracy:0.898398 logloss:0.770995
# 	trees: 205, Out-of-bag evaluation: accuracy:0.902718 logloss:0.772011
# 	trees: 215, Out-of-bag evaluation: accuracy:0.901935 logloss:0.77328
# 	trees: 225, Out-of-bag evaluation: accuracy:0.901935 logloss:0.772008
# 	trees: 235, Out-of-bag evaluation: accuracy:0.9035 logloss:0.773198
# 	trees: 245, Out-of-bag evaluation: accuracy:0.909385 logloss:0.77282
# 	trees: 255, Out-of-bag evaluation: accuracy:0.909385 logloss:0.773905
# 	trees: 265, Out-of-bag evaluation: accuracy:0.908602 logloss:0.773461
# 	trees: 275, Out-of-bag evaluation: accuracy:0.90782 logloss:0.77179
# 	trees: 285, Out-of-bag evaluation: accuracy:0.9035 logloss:0.773099
# 	trees: 295, Out-of-bag evaluation: accuracy:0.901935 logloss:0.61315
# 	trees: 300, Out-of-bag evaluation: accuracy:0.902718 logloss:0.613803

# %%
# Model features
model.make_inspector().features()
# Out:
# ["10Percentile" (1; #0),
#  "90Percentile" (1; #1),
#  "Energy" (1; #2),
#  "Entropy" (1; #3),
#  "InterquartileRange" (1; #4),
#  "Kurtosis" (1; #5),
#  "Maximum" (1; #6),
#  "Mean" (1; #7),
#  "MeanAbsoluteDeviation" (1; #8),
#  "Median" (1; #9),
#  "Minimum" (1; #10),
#  "Range" (1; #11),
#  "RobustMeanAbsoluteDeviation" (1; #12),
#  "RootMeanSquared" (1; #13),
#  "Skewness" (1; #14),
#  "TotalEnergy" (1; #15),
#  "Uniformity" (1; #16),
#  "Variance" (1; #17)]

# %%
# Feature importance
model.make_inspector().variable_importances()
# Out:
# {'INV_MEAN_MIN_DEPTH': [("Median" (1; #9), 0.25160588566604425),
#   ("10Percentile" (1; #0), 0.21976543003581075),
#   ("TotalEnergy" (1; #15), 0.21138862075854215),
#   ("RootMeanSquared" (1; #13), 0.21046897245981777),
#   ("Energy" (1; #2), 0.2088241145522489),
#   ("Mean" (1; #7), 0.19436866151539536),
#   ("InterquartileRange" (1; #4), 0.18495206701198347),
#   ("Uniformity" (1; #16), 0.1839343924455974),
#   ("RobustMeanAbsoluteDeviation" (1; #12), 0.1797082187703462),
#   ("Minimum" (1; #10), 0.176720991648519),
#   ("Maximum" (1; #6), 0.17582828371579126),
#   ("90Percentile" (1; #1), 0.1755367423447412),
#   ("Entropy" (1; #3), 0.17361016604508886),
#   ("Kurtosis" (1; #5), 0.17293242847465312),
#   ("MeanAbsoluteDeviation" (1; #8), 0.17285134567844396),
#   ("Variance" (1; #17), 0.1712509271461984),
#   ("Range" (1; #11), 0.17112127984628966),
#   ("Skewness" (1; #14), 0.17103426196682975)],
#  'SUM_SCORE': [("Median" (1; #9), 28333.784790736885),
#   ("Energy" (1; #2), 20540.821096512573),
#   ("TotalEnergy" (1; #15), 20274.465781974897),
#   ("RootMeanSquared" (1; #13), 19781.71052801301),
#   ("Mean" (1; #7), 10042.195052640775),
#   ("10Percentile" (1; #0), 8261.017970955902),
#   ("Maximum" (1; #6), 4992.438602491358),
#   ("90Percentile" (1; #1), 4937.008058909142),
#   ("Uniformity" (1; #16), 3515.7414732242246),
#   ("InterquartileRange" (1; #4), 3302.3638729786585),
#   ("Entropy" (1; #3), 2753.6165871379144),
#   ("Kurtosis" (1; #5), 2636.1939736535646),
#   ("RobustMeanAbsoluteDeviation" (1; #12), 2604.979723346754),
#   ("Minimum" (1; #10), 2570.8822321547023),
#   ("Range" (1; #11), 2443.958835345283),
#   ("MeanAbsoluteDeviation" (1; #8), 2101.979198263973),
#   ("Variance" (1; #17), 2080.7117148375573),
#   ("Skewness" (1; #14), 1853.3416813074139)],
#  'NUM_AS_ROOT': [("Median" (1; #9), 75.0),
#   ("Energy" (1; #2), 57.0),
#   ("RootMeanSquared" (1; #13), 56.0),
#   ("TotalEnergy" (1; #15), 56.0),
#   ("Mean" (1; #7), 24.0),
#   ("90Percentile" (1; #1), 11.0),
#   ("Maximum" (1; #6), 10.0),
#   ("10Percentile" (1; #0), 9.0),
#   ("Entropy" (1; #3), 1.0),
#   ("Minimum" (1; #10), 1.0)],
#  'NUM_NODES': [("Median" (1; #9), 465.0),
#   ("10Percentile" (1; #0), 390.0),
#   ("Uniformity" (1; #16), 343.0),
#   ("InterquartileRange" (1; #4), 325.0),
#   ("Energy" (1; #2), 296.0),
#   ("Mean" (1; #7), 289.0),
#   ("RootMeanSquared" (1; #13), 284.0),
#   ("Kurtosis" (1; #5), 282.0),
#   ("TotalEnergy" (1; #15), 278.0),
#   ("Maximum" (1; #6), 276.0),
#   ("RobustMeanAbsoluteDeviation" (1; #12), 276.0),
#   ("Entropy" (1; #3), 275.0),
#   ("Range" (1; #11), 259.0),
#   ("MeanAbsoluteDeviation" (1; #8), 246.0),
#   ("Variance" (1; #17), 244.0),
#   ("Skewness" (1; #14), 240.0),
#   ("90Percentile" (1; #1), 233.0),
#   ("Minimum" (1; #10), 221.0)]}

# %%
# Model self evaluation
model.make_inspector().evaluation()
# Out:
# Evaluation(num_examples=737, accuracy=0.9027178954593877, loss=0.613802852996675, rmse=None, ndcg=None, aucs=None, auuc=None, qini=None)

# %%
logs = model.make_inspector().training_logs()

plt.figure(figsize=(12, 4))
plt.subplot(1, 2, 1)
plt.plot([log.num_trees for log in logs], [log.evaluation.accuracy for log in logs])
plt.xlabel("Number of trees")
plt.ylabel("Accuracy (out-of-bag)")
plt.subplot(1, 2, 2)
plt.plot([log.num_trees for log in logs], [log.evaluation.loss for log in logs])
plt.xlabel("Number of trees")
plt.ylabel("Logloss (out-of-bag)")
plt.show()

# %% [markdown]
# Calculate the score of our hold-out validation dataset

# %%
predictions = model.predict(val_ds)
y_true      = validation_data["label"]

from sklearn.metrics import roc_auc_score
ROC_AUC = roc_auc_score(y_true, predictions)
print("The ROC AUC score is %.5f" % ROC_AUC )
# Out:
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 65ms/step
# The ROC AUC score is 0.95341

# %%
# Compute binary classification metrics with sklearn
import numpy as np
from sklearn.metrics import (
    accuracy_score,
    precision_score,
    recall_score,
    f1_score,
    roc_auc_score,
    average_precision_score,
    confusion_matrix,
    classification_report,
    matthews_corrcoef,
    log_loss,
    brier_score_loss,
)

# Get predictions (probabilities or class labels)
preds = model.predict(test_ds)
# If model outputs probabilities, convert to labels by threshold 0.5
if preds.ndim == 2:
    # For TFDF classification, preds may be class probabilities with shape (N, 2)
    if preds.shape[1] == 2:
        pos_probs = preds[:, 1]
    else:
        # If single-probability column (positive class)
        pos_probs = preds[:, -1]
    y_pred = (pos_probs >= 0.5).astype(int)
else:
    # Already class labels
    y_pred = preds.astype(int)
    pos_probs = None

# Ground truth labels (must be 0/1 integers)
y_true = test_data["label"].astype(int).to_numpy()

# Core metrics
metrics = {}
metrics["accuracy"] = accuracy_score(y_true, y_pred)
metrics["precision"] = precision_score(y_true, y_pred, zero_division=0)
metrics["recall"] = recall_score(y_true, y_pred, zero_division=0)
metrics["f1"] = f1_score(y_true, y_pred, zero_division=0)
metrics["mcc"] = matthews_corrcoef(y_true, y_pred)

# Probabilistic metrics (only if we have probabilities)
if pos_probs is not None:
    metrics["roc_auc"] = roc_auc_score(y_true, pos_probs)
    metrics["pr_auc"] = average_precision_score(y_true, pos_probs)
    metrics["log_loss"] = log_loss(y_true, pos_probs, labels=[0,1])
    metrics["brier_score"] = brier_score_loss(y_true, pos_probs)

# Confusion matrix and detailed report
cm = confusion_matrix(y_true, y_pred, labels=[0,1])
report = classification_report(y_true, y_pred, digits=4)

print("Sklearn binary metrics:")
for k, v in metrics.items():
    print(f"{k}: {v:.4f}")
print("\nConfusion matrix:\n", cm)
print("\nClassification report:\n", report)
# Out:
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 71ms/step
# Sklearn binary metrics:
# accuracy: 0.9245
# precision: 0.7273
# recall: 0.7742
# f1: 0.7500
# mcc: 0.7061
# roc_auc: 0.9619
# pr_auc: 0.8743
# log_loss: 0.1616
# brier_score: 0.0492
#
# Confusion matrix:
#  [[172   9]
#  [  7  24]]
#
# Classification report:
#                precision    recall  f1-score   support
#
#            0     0.9609    0.9503    0.9556       181
#            1     0.7273    0.7742    0.7500        31
#
#     accuracy                         0.9245       212
#    macro avg     0.8441    0.8622    0.8528       212
# weighted avg     0.9267    0.9245    0.9255       212
