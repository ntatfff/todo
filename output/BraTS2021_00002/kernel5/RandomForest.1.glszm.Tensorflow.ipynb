# %%
# Import packages and modules
import numpy  as np
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow_decision_forests as tfdf

from sklearn.model_selection import train_test_split
# Out:
# 2026-08-13 04:28:18.413736: I tensorflow/core/util/port.cc:113] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2026-08-13 04:28:18.787666: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2026-08-13 04:28:23.755751: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
# Check the version of TensorFlow Decision Forests
print("Found TensorFlow Decision Forests v" + tfdf.__version__)
# Out:
# Found TensorFlow Decision Forests v1.9.1

# %%
datasetPath = 'dataset/firstorder/kernel5/dataset.csv'

# %%
# Parameters
datasetPath = "dataset/glszm/kernel5/1.dataset.csv"

# %%
# train/validation/test = 70/10/20
dataset = pd.read_csv(datasetPath)

train_data, temp_data = train_test_split(dataset, test_size=0.3, random_state=42)
validation_data, test_data = train_test_split(temp_data, test_size=2/3, random_state=42)

# %%
from sklearn.utils.class_weight import compute_class_weight

# tinh class weight tren tap train
classes = np.array([0, 1])
weights = compute_class_weight(class_weight="balanced", classes=classes, y=train_data["label"])
class_weight = {0: weights[0], 1: weights[1]}

# gan sample_weight cho tung dong
train_data["sample_weight"] = train_data["label"].map(class_weight)
validation_data["sample_weight"] = validation_data["label"].map(class_weight)
test_data["sample_weight"] = test_data["label"].map(class_weight)

# Convert the dataset into a TensorFlow dataset.
train_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    train_data, label="label", weight="sample_weight"
)         
val_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    validation_data, label="label", weight="sample_weight"
)
test_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    test_data, label="label", weight="sample_weight"
)
# Out:
# 2026-08-13 04:28:37.492482: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:984] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2026-08-13 04:28:37.494183: W tensorflow/core/common_runtime/gpu/gpu_device.cc:2251] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...

# %%
import keras

# %%
# %%time

# Train a Random Forest model.
model = tfdf.keras.RandomForestModel()

# Add evaluation metrics
model.compile(
    metrics=["accuracy"]
)
model.fit(x=train_ds)

# # Train a Gradient Boosted Trees model.
# model = tfdf.keras.GradientBoostedTreesModel(num_trees=1500)
# model.fit(train_ds)
# Out:
# Use /tmp/tmpra_jjcdw as temporary training directory
# Reading training dataset...
# Training dataset read in 0:00:02.708774. Found 737 examples.
# Training model...
# Model trained in 0:00:00.071853
# Compiling model...
# [INFO 26-08-13 04:28:40.4475 UTC kernel.cc:1233] Loading model from path /tmp/tmpra_jjcdw/model/ with prefix 810ebf000d224293
# [INFO 26-08-13 04:28:40.4638 UTC decision_forest.cc:734] Model loaded with 300 root(s), 12318 node(s), and 16 input feature(s).
# [INFO 26-08-13 04:28:40.4638 UTC abstract_model.cc:1362] Engine "RandomForestOptPred" built
# [INFO 26-08-13 04:28:40.4638 UTC kernel.cc:1061] Use fast generic engine
# Model compiled.
# CPU times: user 5.58 s, sys: 183 ms, total: 5.77 s
# Wall time: 6.1 s

# %%
# Evaluate the model
evaluate = model.evaluate(val_ds, return_dict=True)
print()

for name, value in evaluate.items():
    print(f"{name}: {value:.4f}")
# Out:
# WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 1/1 [==============================] - ETA: 0s - loss: 0.0000e+00 - accuracy: 0.8667
# 1/1 [==============================] - 3s 3s/step - loss: 0.0000e+00 - accuracy: 0.8667
# loss: 0.0000
# accuracy: 0.8667

# %%
# Model Summary
model.summary()
# Out:
# Model: "random_forest_model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
# =================================================================
# Total params: 1 (1.00 Byte)
# Trainable params: 0 (0.00 Byte)
# Non-trainable params: 1 (1.00 Byte)
# _________________________________________________________________
# Type: "RANDOM_FOREST"
# Task: CLASSIFICATION
# Label: "__LABEL"
#
# Input Features (16):
# 	GrayLevelNonUniformity
# 	GrayLevelNonUniformityNormalized
# 	GrayLevelVariance
# 	HighGrayLevelZoneEmphasis
# 	LargeAreaEmphasis
# 	LargeAreaHighGrayLevelEmphasis
# 	LargeAreaLowGrayLevelEmphasis
# 	LowGrayLevelZoneEmphasis
# 	SizeZoneNonUniformity
# 	SizeZoneNonUniformityNormalized
# 	SmallAreaEmphasis
# 	SmallAreaHighGrayLevelEmphasis
# 	SmallAreaLowGrayLevelEmphasis
# 	ZoneEntropy
# 	ZonePercentage
# 	ZoneVariance
#
# Trained with weights
#
# Variable Importance: INV_MEAN_MIN_DEPTH:
#     1.        "HighGrayLevelZoneEmphasis"  0.271272 ################
#     2.   "SmallAreaHighGrayLevelEmphasis"  0.237605 ##########
#     3.         "LowGrayLevelZoneEmphasis"  0.228407 #########
#     4.    "SmallAreaLowGrayLevelEmphasis"  0.218311 #######
#     5.           "GrayLevelNonUniformity"  0.215078 #######
#     6.   "LargeAreaHighGrayLevelEmphasis"  0.212332 ######
#     7.    "LargeAreaLowGrayLevelEmphasis"  0.185547 ##
#     8. "GrayLevelNonUniformityNormalized"  0.177970 #
#     9.                      "ZoneEntropy"  0.177353 #
#    10.                "GrayLevelVariance"  0.177276 #
#    11.                     "ZoneVariance"  0.173316
#    12.                "LargeAreaEmphasis"  0.172948
#    13.                   "ZonePercentage"  0.171040
#    14.            "SizeZoneNonUniformity"  0.171037
#    15.                "SmallAreaEmphasis"  0.168850
#    16.  "SizeZoneNonUniformityNormalized"  0.167810
#
# Variable Importance: NUM_AS_ROOT:
#     1.       "HighGrayLevelZoneEmphasis" 87.000000 ################
#     2.  "SmallAreaHighGrayLevelEmphasis" 65.000000 ###########
#     3.        "LowGrayLevelZoneEmphasis" 54.000000 #########
#     4.   "SmallAreaLowGrayLevelEmphasis" 35.000000 ######
#     5.  "LargeAreaHighGrayLevelEmphasis" 19.000000 ###
#     6.   "LargeAreaLowGrayLevelEmphasis" 15.000000 ##
#     7.                     "ZoneEntropy" 12.000000 ##
#     8.          "GrayLevelNonUniformity" 10.000000 #
#     9.               "GrayLevelVariance"  1.000000
#    10. "SizeZoneNonUniformityNormalized"  1.000000
#    11.               "SmallAreaEmphasis"  1.000000
#
# Variable Importance: NUM_NODES:
#     1.           "GrayLevelNonUniformity" 583.000000 ################
#     2.   "LargeAreaHighGrayLevelEmphasis" 534.000000 #############
#     3.        "HighGrayLevelZoneEmphasis" 504.000000 ############
#     4.         "LowGrayLevelZoneEmphasis" 473.000000 ###########
#     5.   "SmallAreaHighGrayLevelEmphasis" 468.000000 ##########
#     6.    "SmallAreaLowGrayLevelEmphasis" 418.000000 ########
#     7.    "LargeAreaLowGrayLevelEmphasis" 416.000000 ########
#     8. "GrayLevelNonUniformityNormalized" 369.000000 ######
#     9.                      "ZoneEntropy" 347.000000 #####
#    10.                "GrayLevelVariance" 341.000000 #####
#    11.                     "ZoneVariance" 288.000000 ##
#    12.            "SizeZoneNonUniformity" 280.000000 ##
#    13.                "LargeAreaEmphasis" 277.000000 ##
#    14.                "SmallAreaEmphasis" 243.000000
#    15.                   "ZonePercentage" 239.000000
#    16.  "SizeZoneNonUniformityNormalized" 229.000000
#
# Variable Importance: SUM_SCORE:
#     1.        "HighGrayLevelZoneEmphasis" 34665.084825 ################
#     2.   "SmallAreaHighGrayLevelEmphasis" 24965.311473 ###########
#     3.         "LowGrayLevelZoneEmphasis" 18089.730196 #######
#     4.    "SmallAreaLowGrayLevelEmphasis" 13313.781214 #####
#     5.           "GrayLevelNonUniformity" 10533.856105 ####
#     6.   "LargeAreaHighGrayLevelEmphasis" 10453.856643 ####
#     7.    "LargeAreaLowGrayLevelEmphasis" 5029.339962 #
#     8.                      "ZoneEntropy" 4338.369388 #
#     9.                "GrayLevelVariance" 4262.579163 #
#    10. "GrayLevelNonUniformityNormalized" 4257.063206 #
#    11.                     "ZoneVariance" 2527.595876
#    12.                "LargeAreaEmphasis" 2511.886889
#    13.            "SizeZoneNonUniformity" 2283.461292
#    14.                   "ZonePercentage" 1893.433255
#    15.                "SmallAreaEmphasis" 1762.337758
#    16.  "SizeZoneNonUniformityNormalized" 1531.858654
#
#
#
# Winner takes all: true
# Out-of-bag evaluation: accuracy:0.901318 logloss:0.232195
# Number of trees: 300
# Total number of nodes: 12318
#
# Number of nodes by tree:
# Count: 300 Average: 41.06 StdDev: 4.68861
# Min: 29 Max: 55 Ignored: 0
# ----------------------------------------------
# [ 29, 30)  2   0.67%   0.67%
# [ 30, 31)  0   0.00%   0.67%
# [ 31, 33)  5   1.67%   2.33% #
# [ 33, 34) 12   4.00%   6.33% ##
# [ 34, 35)  0   0.00%   6.33%
# [ 35, 37) 23   7.67%  14.00% ####
# [ 37, 38) 40  13.33%  27.33% ########
# [ 38, 39)  0   0.00%  27.33%
# [ 39, 41) 40  13.33%  40.67% ########
# [ 41, 42) 52  17.33%  58.00% ##########
# [ 42, 43)  0   0.00%  58.00%
# [ 43, 45) 48  16.00%  74.00% #########
# [ 45, 46) 32  10.67%  84.67% ######
# [ 46, 47)  0   0.00%  84.67%
# [ 47, 49) 24   8.00%  92.67% #####
# [ 49, 50) 15   5.00%  97.67% ###
# [ 50, 51)  0   0.00%  97.67%
# [ 51, 53)  4   1.33%  99.00% #
# [ 53, 54)  2   0.67%  99.67%
# [ 54, 55]  1   0.33% 100.00%
#
# Depth by leafs:
# Count: 6309 Average: 5.26312 StdDev: 1.73718
# Min: 1 Max: 12 Ignored: 0
# ----------------------------------------------
# [  1,  2)    4   0.06%   0.06%
# [  2,  3)  224   3.55%   3.61% #
# [  3,  4)  702  11.13%  14.74% #####
# [  4,  5) 1300  20.61%  35.35% #########
# [  5,  6) 1498  23.74%  59.09% ##########
# [  6,  7) 1193  18.91%  78.00% ########
# [  7,  8)  714  11.32%  89.32% #####
# [  8,  9)  388   6.15%  95.47% ###
# [  9, 10)  191   3.03%  98.49% #
# [ 10, 11)   71   1.13%  99.62%
# [ 11, 12)   20   0.32%  99.94%
# [ 12, 12]    4   0.06% 100.00%
#
# Number of training obs by leaf:
# Count: 6309 Average: 35.0452 StdDev: 81.9601
# Min: 5 Max: 546 Ignored: 0
# ----------------------------------------------
# [   5,  32) 5117  81.11%  81.11% ##########
# [  32,  59)  552   8.75%  89.86% #
# [  59,  86)  158   2.50%  92.36%
# [  86, 113)   61   0.97%  93.33%
# [ 113, 140)   30   0.48%  93.80%
# [ 140, 167)   25   0.40%  94.20%
# [ 167, 194)   29   0.46%  94.66%
# [ 194, 221)   30   0.48%  95.13%
# [ 221, 248)   21   0.33%  95.47%
# [ 248, 276)   30   0.48%  95.94%
# [ 276, 303)   28   0.44%  96.39%
# [ 303, 330)   20   0.32%  96.70%
# [ 330, 357)   26   0.41%  97.12%
# [ 357, 384)   26   0.41%  97.53%
# [ 384, 411)   39   0.62%  98.15%
# [ 411, 438)   48   0.76%  98.91%
# [ 438, 465)   44   0.70%  99.60%
# [ 465, 492)   18   0.29%  99.89%
# [ 492, 519)    5   0.08%  99.97%
# [ 519, 546]    2   0.03% 100.00%
#
# Attribute in nodes:
# 	583 : GrayLevelNonUniformity [NUMERICAL]
# 	534 : LargeAreaHighGrayLevelEmphasis [NUMERICAL]
# 	504 : HighGrayLevelZoneEmphasis [NUMERICAL]
# 	473 : LowGrayLevelZoneEmphasis [NUMERICAL]
# 	468 : SmallAreaHighGrayLevelEmphasis [NUMERICAL]
# 	418 : SmallAreaLowGrayLevelEmphasis [NUMERICAL]
# 	416 : LargeAreaLowGrayLevelEmphasis [NUMERICAL]
# 	369 : GrayLevelNonUniformityNormalized [NUMERICAL]
# 	347 : ZoneEntropy [NUMERICAL]
# 	341 : GrayLevelVariance [NUMERICAL]
# 	288 : ZoneVariance [NUMERICAL]
# 	280 : SizeZoneNonUniformity [NUMERICAL]
# 	277 : LargeAreaEmphasis [NUMERICAL]
# 	243 : SmallAreaEmphasis [NUMERICAL]
# 	239 : ZonePercentage [NUMERICAL]
# 	229 : SizeZoneNonUniformityNormalized [NUMERICAL]
#
# Attribute in nodes with depth <= 0:
# 	87 : HighGrayLevelZoneEmphasis [NUMERICAL]
# 	65 : SmallAreaHighGrayLevelEmphasis [NUMERICAL]
# 	54 : LowGrayLevelZoneEmphasis [NUMERICAL]
# 	35 : SmallAreaLowGrayLevelEmphasis [NUMERICAL]
# 	19 : LargeAreaHighGrayLevelEmphasis [NUMERICAL]
# 	15 : LargeAreaLowGrayLevelEmphasis [NUMERICAL]
# 	12 : ZoneEntropy [NUMERICAL]
# 	10 : GrayLevelNonUniformity [NUMERICAL]
# 	1 : SmallAreaEmphasis [NUMERICAL]
# 	1 : SizeZoneNonUniformityNormalized [NUMERICAL]
# 	1 : GrayLevelVariance [NUMERICAL]
#
# Attribute in nodes with depth <= 1:
# 	198 : HighGrayLevelZoneEmphasis [NUMERICAL]
# 	141 : SmallAreaHighGrayLevelEmphasis [NUMERICAL]
# 	141 : LowGrayLevelZoneEmphasis [NUMERICAL]
# 	124 : SmallAreaLowGrayLevelEmphasis [NUMERICAL]
# 	86 : LargeAreaHighGrayLevelEmphasis [NUMERICAL]
# 	73 : GrayLevelNonUniformity [NUMERICAL]
# 	27 : LargeAreaLowGrayLevelEmphasis [NUMERICAL]
# 	27 : GrayLevelVariance [NUMERICAL]
# 	25 : GrayLevelNonUniformityNormalized [NUMERICAL]
# 	24 : ZoneEntropy [NUMERICAL]
# 	8 : SizeZoneNonUniformityNormalized [NUMERICAL]
# 	6 : SmallAreaEmphasis [NUMERICAL]
# 	5 : SizeZoneNonUniformity [NUMERICAL]
# 	5 : LargeAreaEmphasis [NUMERICAL]
# 	3 : ZoneVariance [NUMERICAL]
# 	3 : ZonePercentage [NUMERICAL]
#
# Attribute in nodes with depth <= 2:
# 	275 : HighGrayLevelZoneEmphasis [NUMERICAL]
# 	218 : LowGrayLevelZoneEmphasis [NUMERICAL]
# 	213 : SmallAreaHighGrayLevelEmphasis [NUMERICAL]
# 	199 : SmallAreaLowGrayLevelEmphasis [NUMERICAL]
# 	190 : LargeAreaHighGrayLevelEmphasis [NUMERICAL]
# 	180 : GrayLevelNonUniformity [NUMERICAL]
# 	98 : LargeAreaLowGrayLevelEmphasis [NUMERICAL]
# 	90 : GrayLevelVariance [NUMERICAL]
# 	88 : GrayLevelNonUniformityNormalized [NUMERICAL]
# 	67 : ZoneEntropy [NUMERICAL]
# 	57 : ZoneVariance [NUMERICAL]
# 	48 : LargeAreaEmphasis [NUMERICAL]
# 	44 : SizeZoneNonUniformity [NUMERICAL]
# 	38 : SmallAreaEmphasis [NUMERICAL]
# 	36 : ZonePercentage [NUMERICAL]
# 	23 : SizeZoneNonUniformityNormalized [NUMERICAL]
#
# Attribute in nodes with depth <= 3:
# 	350 : HighGrayLevelZoneEmphasis [NUMERICAL]
# 	322 : GrayLevelNonUniformity [NUMERICAL]
# 	304 : LargeAreaHighGrayLevelEmphasis [NUMERICAL]
# 	302 : LowGrayLevelZoneEmphasis [NUMERICAL]
# 	276 : SmallAreaHighGrayLevelEmphasis [NUMERICAL]
# 	270 : SmallAreaLowGrayLevelEmphasis [NUMERICAL]
# 	202 : LargeAreaLowGrayLevelEmphasis [NUMERICAL]
# 	187 : GrayLevelNonUniformityNormalized [NUMERICAL]
# 	161 : GrayLevelVariance [NUMERICAL]
# 	146 : ZoneEntropy [NUMERICAL]
# 	113 : ZoneVariance [NUMERICAL]
# 	107 : LargeAreaEmphasis [NUMERICAL]
# 	102 : SizeZoneNonUniformity [NUMERICAL]
# 	94 : ZonePercentage [NUMERICAL]
# 	85 : SmallAreaEmphasis [NUMERICAL]
# 	77 : SizeZoneNonUniformityNormalized [NUMERICAL]
#
# Attribute in nodes with depth <= 5:
# 	506 : GrayLevelNonUniformity [NUMERICAL]
# 	477 : LargeAreaHighGrayLevelEmphasis [NUMERICAL]
# 	448 : HighGrayLevelZoneEmphasis [NUMERICAL]
# 	425 : LowGrayLevelZoneEmphasis [NUMERICAL]
# 	411 : SmallAreaHighGrayLevelEmphasis [NUMERICAL]
# 	373 : SmallAreaLowGrayLevelEmphasis [NUMERICAL]
# 	344 : LargeAreaLowGrayLevelEmphasis [NUMERICAL]
# 	319 : GrayLevelNonUniformityNormalized [NUMERICAL]
# 	282 : GrayLevelVariance [NUMERICAL]
# 	274 : ZoneEntropy [NUMERICAL]
# 	227 : SizeZoneNonUniformity [NUMERICAL]
# 	227 : LargeAreaEmphasis [NUMERICAL]
# 	226 : ZoneVariance [NUMERICAL]
# 	197 : ZonePercentage [NUMERICAL]
# 	192 : SmallAreaEmphasis [NUMERICAL]
# 	176 : SizeZoneNonUniformityNormalized [NUMERICAL]
#
# Condition type in nodes:
# 	6009 : HigherCondition
# Condition type in nodes with depth <= 0:
# 	300 : HigherCondition
# Condition type in nodes with depth <= 1:
# 	896 : HigherCondition
# Condition type in nodes with depth <= 2:
# 	1864 : HigherCondition
# Condition type in nodes with depth <= 3:
# 	3098 : HigherCondition
# Condition type in nodes with depth <= 5:
# 	5104 : HigherCondition
# Node format: NOT_SET
#
# Training OOB:
# 	trees: 1, Out-of-bag evaluation: accuracy:0.936227 logloss:2.29862
# 	trees: 13, Out-of-bag evaluation: accuracy:0.866574 logloss:2.28963
# 	trees: 24, Out-of-bag evaluation: accuracy:0.873188 logloss:1.34113
# 	trees: 34, Out-of-bag evaluation: accuracy:0.877776 logloss:1.15184
# 	trees: 45, Out-of-bag evaluation: accuracy:0.894532 logloss:0.788904
# 	trees: 55, Out-of-bag evaluation: accuracy:0.875387 logloss:0.456333
# 	trees: 65, Out-of-bag evaluation: accuracy:0.882969 logloss:0.273916
# 	trees: 75, Out-of-bag evaluation: accuracy:0.902114 logloss:0.275213
# 	trees: 85, Out-of-bag evaluation: accuracy:0.887556 logloss:0.251095
# 	trees: 95, Out-of-bag evaluation: accuracy:0.900522 logloss:0.24664
# 	trees: 105, Out-of-bag evaluation: accuracy:0.901318 logloss:0.239079
# 	trees: 115, Out-of-bag evaluation: accuracy:0.900522 logloss:0.238674
# 	trees: 125, Out-of-bag evaluation: accuracy:0.901318 logloss:0.240443
# 	trees: 135, Out-of-bag evaluation: accuracy:0.895934 logloss:0.238632
# 	trees: 146, Out-of-bag evaluation: accuracy:0.900522 logloss:0.233755
# 	trees: 157, Out-of-bag evaluation: accuracy:0.901318 logloss:0.233773
# 	trees: 167, Out-of-bag evaluation: accuracy:0.901318 logloss:0.233682
# 	trees: 178, Out-of-bag evaluation: accuracy:0.901318 logloss:0.235161
# 	trees: 188, Out-of-bag evaluation: accuracy:0.901318 logloss:0.238205
# 	trees: 198, Out-of-bag evaluation: accuracy:0.901318 logloss:0.237123
# 	trees: 208, Out-of-bag evaluation: accuracy:0.896731 logloss:0.236528
# 	trees: 218, Out-of-bag evaluation: accuracy:0.897527 logloss:0.235862
# 	trees: 228, Out-of-bag evaluation: accuracy:0.902114 logloss:0.234638
# 	trees: 238, Out-of-bag evaluation: accuracy:0.901318 logloss:0.235452
# 	trees: 250, Out-of-bag evaluation: accuracy:0.901318 logloss:0.23748
# 	trees: 260, Out-of-bag evaluation: accuracy:0.900522 logloss:0.235865
# 	trees: 270, Out-of-bag evaluation: accuracy:0.895934 logloss:0.235381
# 	trees: 280, Out-of-bag evaluation: accuracy:0.901318 logloss:0.233692
# 	trees: 290, Out-of-bag evaluation: accuracy:0.901318 logloss:0.233322
# 	trees: 300, Out-of-bag evaluation: accuracy:0.901318 logloss:0.232195

# %%
# Model features
model.make_inspector().features()
# Out:
# ["GrayLevelNonUniformity" (1; #0),
#  "GrayLevelNonUniformityNormalized" (1; #1),
#  "GrayLevelVariance" (1; #2),
#  "HighGrayLevelZoneEmphasis" (1; #3),
#  "LargeAreaEmphasis" (1; #4),
#  "LargeAreaHighGrayLevelEmphasis" (1; #5),
#  "LargeAreaLowGrayLevelEmphasis" (1; #6),
#  "LowGrayLevelZoneEmphasis" (1; #7),
#  "SizeZoneNonUniformity" (1; #8),
#  "SizeZoneNonUniformityNormalized" (1; #9),
#  "SmallAreaEmphasis" (1; #10),
#  "SmallAreaHighGrayLevelEmphasis" (1; #11),
#  "SmallAreaLowGrayLevelEmphasis" (1; #12),
#  "ZoneEntropy" (1; #13),
#  "ZonePercentage" (1; #14),
#  "ZoneVariance" (1; #15)]

# %%
# Feature importance
model.make_inspector().variable_importances()
# Out:
# {'INV_MEAN_MIN_DEPTH': [("HighGrayLevelZoneEmphasis" (1; #3),
#    0.2712717535574387),
#   ("SmallAreaHighGrayLevelEmphasis" (1; #11), 0.2376045091566927),
#   ("LowGrayLevelZoneEmphasis" (1; #7), 0.2284068752216111),
#   ("SmallAreaLowGrayLevelEmphasis" (1; #12), 0.2183108932106875),
#   ("GrayLevelNonUniformity" (1; #0), 0.21507804560870689),
#   ("LargeAreaHighGrayLevelEmphasis" (1; #5), 0.21233224975147705),
#   ("LargeAreaLowGrayLevelEmphasis" (1; #6), 0.18554660564255065),
#   ("GrayLevelNonUniformityNormalized" (1; #1), 0.17797039119014765),
#   ("ZoneEntropy" (1; #13), 0.1773529642458819),
#   ("GrayLevelVariance" (1; #2), 0.17727577656990878),
#   ("ZoneVariance" (1; #15), 0.17331552524150742),
#   ("LargeAreaEmphasis" (1; #4), 0.17294755841370718),
#   ("ZonePercentage" (1; #14), 0.17104014405816448),
#   ("SizeZoneNonUniformity" (1; #8), 0.1710365443694246),
#   ("SmallAreaEmphasis" (1; #10), 0.16885008919131847),
#   ("SizeZoneNonUniformityNormalized" (1; #9), 0.16781024194431468)],
#  'SUM_SCORE': [("HighGrayLevelZoneEmphasis" (1; #3), 34665.08482461733),
#   ("SmallAreaHighGrayLevelEmphasis" (1; #11), 24965.311472784062),
#   ("LowGrayLevelZoneEmphasis" (1; #7), 18089.73019612982),
#   ("SmallAreaLowGrayLevelEmphasis" (1; #12), 13313.781214357901),
#   ("GrayLevelNonUniformity" (1; #0), 10533.856105123574),
#   ("LargeAreaHighGrayLevelEmphasis" (1; #5), 10453.856642958499),
#   ("LargeAreaLowGrayLevelEmphasis" (1; #6), 5029.33996167173),
#   ("ZoneEntropy" (1; #13), 4338.369387567184),
#   ("GrayLevelVariance" (1; #2), 4262.579163005967),
#   ("GrayLevelNonUniformityNormalized" (1; #1), 4257.0632055246215),
#   ("ZoneVariance" (1; #15), 2527.59587641368),
#   ("LargeAreaEmphasis" (1; #4), 2511.88688874562),
#   ("SizeZoneNonUniformity" (1; #8), 2283.4612921637017),
#   ("ZonePercentage" (1; #14), 1893.4332554860596),
#   ("SmallAreaEmphasis" (1; #10), 1762.337758147121),
#   ("SizeZoneNonUniformityNormalized" (1; #9), 1531.8586540002811)],
#  'NUM_AS_ROOT': [("HighGrayLevelZoneEmphasis" (1; #3), 87.0),
#   ("SmallAreaHighGrayLevelEmphasis" (1; #11), 65.0),
#   ("LowGrayLevelZoneEmphasis" (1; #7), 54.0),
#   ("SmallAreaLowGrayLevelEmphasis" (1; #12), 35.0),
#   ("LargeAreaHighGrayLevelEmphasis" (1; #5), 19.0),
#   ("LargeAreaLowGrayLevelEmphasis" (1; #6), 15.0),
#   ("ZoneEntropy" (1; #13), 12.0),
#   ("GrayLevelNonUniformity" (1; #0), 10.0),
#   ("GrayLevelVariance" (1; #2), 1.0),
#   ("SizeZoneNonUniformityNormalized" (1; #9), 1.0),
#   ("SmallAreaEmphasis" (1; #10), 1.0)],
#  'NUM_NODES': [("GrayLevelNonUniformity" (1; #0), 583.0),
#   ("LargeAreaHighGrayLevelEmphasis" (1; #5), 534.0),
#   ("HighGrayLevelZoneEmphasis" (1; #3), 504.0),
#   ("LowGrayLevelZoneEmphasis" (1; #7), 473.0),
#   ("SmallAreaHighGrayLevelEmphasis" (1; #11), 468.0),
#   ("SmallAreaLowGrayLevelEmphasis" (1; #12), 418.0),
#   ("LargeAreaLowGrayLevelEmphasis" (1; #6), 416.0),
#   ("GrayLevelNonUniformityNormalized" (1; #1), 369.0),
#   ("ZoneEntropy" (1; #13), 347.0),
#   ("GrayLevelVariance" (1; #2), 341.0),
#   ("ZoneVariance" (1; #15), 288.0),
#   ("SizeZoneNonUniformity" (1; #8), 280.0),
#   ("LargeAreaEmphasis" (1; #4), 277.0),
#   ("SmallAreaEmphasis" (1; #10), 243.0),
#   ("ZonePercentage" (1; #14), 239.0),
#   ("SizeZoneNonUniformityNormalized" (1; #9), 229.0)]}

# %%
# Model self evaluation
model.make_inspector().evaluation()
# Out:
# Evaluation(num_examples=737, accuracy=0.9013177129227106, loss=0.23219483139609132, rmse=None, ndcg=None, aucs=None, auuc=None, qini=None)

# %%
logs = model.make_inspector().training_logs()

plt.figure(figsize=(12, 4))
plt.subplot(1, 2, 1)
plt.plot([log.num_trees for log in logs], [log.evaluation.accuracy for log in logs])
plt.xlabel("Number of trees")
plt.ylabel("Accuracy (out-of-bag)")
plt.subplot(1, 2, 2)
plt.plot([log.num_trees for log in logs], [log.evaluation.loss for log in logs])
plt.xlabel("Number of trees")
plt.ylabel("Logloss (out-of-bag)")
plt.show()

# %% [markdown]
# Calculate the score of our hold-out validation dataset

# %%
predictions = model.predict(val_ds)
y_true      = validation_data["label"]

from sklearn.metrics import roc_auc_score
ROC_AUC = roc_auc_score(y_true, predictions)
print("The ROC AUC score is %.5f" % ROC_AUC )
# Out:
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 66ms/step
# The ROC AUC score is 0.88703

# %%
# Compute binary classification metrics with sklearn
import numpy as np
from sklearn.metrics import (
    accuracy_score,
    precision_score,
    recall_score,
    f1_score,
    roc_auc_score,
    average_precision_score,
    confusion_matrix,
    classification_report,
    matthews_corrcoef,
    log_loss,
    brier_score_loss,
)

# Get predictions (probabilities or class labels)
preds = model.predict(test_ds)
# If model outputs probabilities, convert to labels by threshold 0.5
if preds.ndim == 2:
    # For TFDF classification, preds may be class probabilities with shape (N, 2)
    if preds.shape[1] == 2:
        pos_probs = preds[:, 1]
    else:
        # If single-probability column (positive class)
        pos_probs = preds[:, -1]
    y_pred = (pos_probs >= 0.5).astype(int)
else:
    # Already class labels
    y_pred = preds.astype(int)
    pos_probs = None

# Ground truth labels (must be 0/1 integers)
y_true = test_data["label"].astype(int).to_numpy()

# Core metrics
metrics = {}
metrics["accuracy"] = accuracy_score(y_true, y_pred)
metrics["precision"] = precision_score(y_true, y_pred, zero_division=0)
metrics["recall"] = recall_score(y_true, y_pred, zero_division=0)
metrics["f1"] = f1_score(y_true, y_pred, zero_division=0)
metrics["mcc"] = matthews_corrcoef(y_true, y_pred)

# Probabilistic metrics (only if we have probabilities)
if pos_probs is not None:
    metrics["roc_auc"] = roc_auc_score(y_true, pos_probs)
    metrics["pr_auc"] = average_precision_score(y_true, pos_probs)
    metrics["log_loss"] = log_loss(y_true, pos_probs, labels=[0,1])
    metrics["brier_score"] = brier_score_loss(y_true, pos_probs)

# Confusion matrix and detailed report
cm = confusion_matrix(y_true, y_pred, labels=[0,1])
report = classification_report(y_true, y_pred, digits=4)

print("Sklearn binary metrics:")
for k, v in metrics.items():
    print(f"{k}: {v:.4f}")
print("\nConfusion matrix:\n", cm)
print("\nClassification report:\n", report)
# Out:
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 71ms/step
# Sklearn binary metrics:
# accuracy: 0.9292
# precision: 0.7083
# recall: 0.6800
# f1: 0.6939
# mcc: 0.6541
# roc_auc: 0.9611
# pr_auc: 0.8397
# log_loss: 0.1526
# brier_score: 0.0474
#
# Confusion matrix:
#  [[180   7]
#  [  8  17]]
#
# Classification report:
#                precision    recall  f1-score   support
#
#            0     0.9574    0.9626    0.9600       187
#            1     0.7083    0.6800    0.6939        25
#
#     accuracy                         0.9292       212
#    macro avg     0.8329    0.8213    0.8269       212
# weighted avg     0.9281    0.9292    0.9286       212
