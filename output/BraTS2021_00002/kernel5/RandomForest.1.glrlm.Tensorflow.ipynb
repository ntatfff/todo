# %%
# Import packages and modules
import numpy  as np
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow_decision_forests as tfdf

from sklearn.model_selection import train_test_split
# Out:
# 2026-08-13 04:27:40.133604: I tensorflow/core/util/port.cc:113] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2026-08-13 04:27:40.520990: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2026-08-13 04:27:45.480168: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
# Check the version of TensorFlow Decision Forests
print("Found TensorFlow Decision Forests v" + tfdf.__version__)
# Out:
# Found TensorFlow Decision Forests v1.9.1

# %%
datasetPath = 'dataset/firstorder/kernel5/dataset.csv'

# %%
# Parameters
datasetPath = "dataset/glrlm/kernel5/1.dataset.csv"

# %%
# train/validation/test = 70/10/20
dataset = pd.read_csv(datasetPath)

train_data, temp_data = train_test_split(dataset, test_size=0.3, random_state=42)
validation_data, test_data = train_test_split(temp_data, test_size=2/3, random_state=42)

# %%
from sklearn.utils.class_weight import compute_class_weight

# tinh class weight tren tap train
classes = np.array([0, 1])
weights = compute_class_weight(class_weight="balanced", classes=classes, y=train_data["label"])
class_weight = {0: weights[0], 1: weights[1]}

# gan sample_weight cho tung dong
train_data["sample_weight"] = train_data["label"].map(class_weight)
validation_data["sample_weight"] = validation_data["label"].map(class_weight)
test_data["sample_weight"] = test_data["label"].map(class_weight)

# Convert the dataset into a TensorFlow dataset.
train_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    train_data, label="label", weight="sample_weight"
)         
val_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    validation_data, label="label", weight="sample_weight"
)
test_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    test_data, label="label", weight="sample_weight"
)
# Out:
# 2026-08-13 04:28:00.155897: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:984] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2026-08-13 04:28:00.157393: W tensorflow/core/common_runtime/gpu/gpu_device.cc:2251] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...

# %%
import keras

# %%
# %%time

# Train a Random Forest model.
model = tfdf.keras.RandomForestModel()

# Add evaluation metrics
model.compile(
    metrics=["accuracy"]
)
model.fit(x=train_ds)

# # Train a Gradient Boosted Trees model.
# model = tfdf.keras.GradientBoostedTreesModel(num_trees=1500)
# model.fit(train_ds)
# Out:
# Use /tmp/tmpx3u0io8_ as temporary training directory
# Reading training dataset...
# Training dataset read in 0:00:02.779724. Found 737 examples.
# Training model...
# Model trained in 0:00:00.067764
# Compiling model...
# [INFO 26-08-13 04:28:03.1761 UTC kernel.cc:1233] Loading model from path /tmp/tmpx3u0io8_/model/ with prefix 00b71a833a5b4925
# [INFO 26-08-13 04:28:03.1901 UTC decision_forest.cc:734] Model loaded with 300 root(s), 11142 node(s), and 16 input feature(s).
# [INFO 26-08-13 04:28:03.1902 UTC abstract_model.cc:1362] Engine "RandomForestOptPred" built
# [INFO 26-08-13 04:28:03.1902 UTC kernel.cc:1061] Use fast generic engine
# Model compiled.
# CPU times: user 5.69 s, sys: 187 ms, total: 5.87 s
# Wall time: 6.17 s

# %%
# Evaluate the model
evaluate = model.evaluate(val_ds, return_dict=True)
print()

for name, value in evaluate.items():
    print(f"{name}: {value:.4f}")
# Out:
# WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 1/1 [==============================] - ETA: 0s - loss: 0.0000e+00 - accuracy: 0.9048
# 1/1 [==============================] - 4s 4s/step - loss: 0.0000e+00 - accuracy: 0.9048
# loss: 0.0000
# accuracy: 0.9048

# %%
# Model Summary
model.summary()
# Out:
# Model: "random_forest_model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
# =================================================================
# Total params: 1 (1.00 Byte)
# Trainable params: 0 (0.00 Byte)
# Non-trainable params: 1 (1.00 Byte)
# _________________________________________________________________
# Type: "RANDOM_FOREST"
# Task: CLASSIFICATION
# Label: "__LABEL"
#
# Input Features (16):
# 	GrayLevelNonUniformity
# 	GrayLevelNonUniformityNormalized
# 	GrayLevelVariance
# 	HighGrayLevelRunEmphasis
# 	LongRunEmphasis
# 	LongRunHighGrayLevelEmphasis
# 	LongRunLowGrayLevelEmphasis
# 	LowGrayLevelRunEmphasis
# 	RunEntropy
# 	RunLengthNonUniformity
# 	RunLengthNonUniformityNormalized
# 	RunPercentage
# 	RunVariance
# 	ShortRunEmphasis
# 	ShortRunHighGrayLevelEmphasis
# 	ShortRunLowGrayLevelEmphasis
#
# Trained with weights
#
# Variable Importance: INV_MEAN_MIN_DEPTH:
#     1.     "LongRunHighGrayLevelEmphasis"  0.320732 ################
#     2.         "HighGrayLevelRunEmphasis"  0.249745 ########
#     3.    "ShortRunHighGrayLevelEmphasis"  0.219574 ####
#     4.     "ShortRunLowGrayLevelEmphasis"  0.212804 ####
#     5.          "LowGrayLevelRunEmphasis"  0.205980 ###
#     6.      "LongRunLowGrayLevelEmphasis"  0.189217 #
#     7.                       "RunEntropy"  0.184557
#     8.                  "LongRunEmphasis"  0.182374
#     9.                      "RunVariance"  0.181788
#    10.           "RunLengthNonUniformity"  0.181165
#    11.                    "RunPercentage"  0.179837
#    12.           "GrayLevelNonUniformity"  0.177977
#    13. "RunLengthNonUniformityNormalized"  0.177711
#    14.                "GrayLevelVariance"  0.177589
#    15.                 "ShortRunEmphasis"  0.176729
#    16. "GrayLevelNonUniformityNormalized"  0.176348
#
# Variable Importance: NUM_AS_ROOT:
#     1.     "LongRunHighGrayLevelEmphasis" 95.000000 ################
#     2.         "HighGrayLevelRunEmphasis" 59.000000 #########
#     3.    "ShortRunHighGrayLevelEmphasis" 43.000000 #######
#     4.     "ShortRunLowGrayLevelEmphasis" 37.000000 ######
#     5.          "LowGrayLevelRunEmphasis" 32.000000 #####
#     6.      "LongRunLowGrayLevelEmphasis" 16.000000 ##
#     7.                  "LongRunEmphasis"  6.000000
#     8.                      "RunVariance"  6.000000
#     9.                    "RunPercentage"  4.000000
#    10. "GrayLevelNonUniformityNormalized"  1.000000
#    11.           "RunLengthNonUniformity"  1.000000
#
# Variable Importance: NUM_NODES:
#     1.     "LongRunHighGrayLevelEmphasis" 778.000000 ################
#     2.         "HighGrayLevelRunEmphasis" 465.000000 #######
#     3.    "ShortRunHighGrayLevelEmphasis" 435.000000 ######
#     4.     "ShortRunLowGrayLevelEmphasis" 413.000000 #####
#     5.                       "RunEntropy" 366.000000 ####
#     6.          "LowGrayLevelRunEmphasis" 339.000000 ###
#     7.           "GrayLevelNonUniformity" 302.000000 ##
#     8.      "LongRunLowGrayLevelEmphasis" 281.000000 #
#     9. "GrayLevelNonUniformityNormalized" 280.000000 #
#    10.                "GrayLevelVariance" 271.000000 #
#    11.                      "RunVariance" 268.000000 #
#    12.           "RunLengthNonUniformity" 258.000000 #
#    13.                  "LongRunEmphasis" 257.000000 #
#    14. "RunLengthNonUniformityNormalized" 248.000000
#    15.                 "ShortRunEmphasis" 241.000000
#    16.                    "RunPercentage" 219.000000
#
# Variable Importance: SUM_SCORE:
#     1.     "LongRunHighGrayLevelEmphasis" 47040.951294 ################
#     2.         "HighGrayLevelRunEmphasis" 25359.156236 ########
#     3.    "ShortRunHighGrayLevelEmphasis" 16474.038305 #####
#     4.     "ShortRunLowGrayLevelEmphasis" 12954.425609 ###
#     5.          "LowGrayLevelRunEmphasis" 10900.160195 ###
#     6.      "LongRunLowGrayLevelEmphasis" 5522.349873 #
#     7.                       "RunEntropy" 3775.153046
#     8.                      "RunVariance" 2737.020826
#     9.           "GrayLevelNonUniformity" 2519.913219
#    10.                  "LongRunEmphasis" 2480.776950
#    11.           "RunLengthNonUniformity" 2466.610583
#    12. "GrayLevelNonUniformityNormalized" 2332.198703
#    13.                "GrayLevelVariance" 2254.765570
#    14.                    "RunPercentage" 2111.518301
#    15.                 "ShortRunEmphasis" 1962.888040
#    16. "RunLengthNonUniformityNormalized" 1945.188829
#
#
#
# Winner takes all: true
# Out-of-bag evaluation: accuracy:0.911947 logloss:0.565522
# Number of trees: 300
# Total number of nodes: 11142
#
# Number of nodes by tree:
# Count: 300 Average: 37.14 StdDev: 4.71809
# Min: 21 Max: 51 Ignored: 0
# ----------------------------------------------
# [ 21, 22)  1   0.33%   0.33%
# [ 22, 24)  0   0.00%   0.33%
# [ 24, 25)  0   0.00%   0.33%
# [ 25, 27)  2   0.67%   1.00%
# [ 27, 28)  2   0.67%   1.67%
# [ 28, 30) 14   4.67%   6.33% ###
# [ 30, 31)  0   0.00%   6.33%
# [ 31, 33) 22   7.33%  13.67% #####
# [ 33, 34) 39  13.00%  26.67% ########
# [ 34, 36) 44  14.67%  41.33% #########
# [ 36, 38) 44  14.67%  56.00% #########
# [ 38, 39)  0   0.00%  56.00%
# [ 39, 41) 47  15.67%  71.67% ##########
# [ 41, 42) 39  13.00%  84.67% ########
# [ 42, 44) 22   7.33%  92.00% #####
# [ 44, 45)  0   0.00%  92.00%
# [ 45, 47) 18   6.00%  98.00% ####
# [ 47, 48)  5   1.67%  99.67% #
# [ 48, 50)  0   0.00%  99.67%
# [ 50, 51]  1   0.33% 100.00%
#
# Depth by leafs:
# Count: 5721 Average: 5.08285 StdDev: 1.64583
# Min: 1 Max: 13 Ignored: 0
# ----------------------------------------------
# [  1,  2)    9   0.16%   0.16%
# [  2,  3)  270   4.72%   4.88% ##
# [  3,  4)  712  12.45%  17.32% #####
# [  4,  5) 1166  20.38%  37.70% #########
# [  5,  6) 1327  23.20%  60.90% ##########
# [  6,  7) 1175  20.54%  81.44% #########
# [  7,  8)  626  10.94%  92.38% #####
# [  8,  9)  298   5.21%  97.59% ##
# [  9, 10)  115   2.01%  99.60% #
# [ 10, 11)   16   0.28%  99.88%
# [ 11, 12)    2   0.03%  99.91%
# [ 12, 13)    3   0.05%  99.97%
# [ 13, 13]    2   0.03% 100.00%
#
# Number of training obs by leaf:
# Count: 5721 Average: 38.6471 StdDev: 82.0767
# Min: 5 Max: 568 Ignored: 0
# ----------------------------------------------
# [   5,  33) 4448  77.75%  77.75% ##########
# [  33,  61)  576  10.07%  87.82% #
# [  61,  89)  124   2.17%  89.98%
# [  89, 117)   67   1.17%  91.16%
# [ 117, 146)   81   1.42%  92.57%
# [ 146, 174)   67   1.17%  93.74%
# [ 174, 202)   36   0.63%  94.37%
# [ 202, 230)   29   0.51%  94.88%
# [ 230, 258)   13   0.23%  95.11%
# [ 258, 287)   20   0.35%  95.46%
# [ 287, 315)   63   1.10%  96.56%
# [ 315, 343)   67   1.17%  97.73%
# [ 343, 371)   31   0.54%  98.27%
# [ 371, 399)   32   0.56%  98.83%
# [ 399, 428)   18   0.31%  99.14%
# [ 428, 456)   11   0.19%  99.34%
# [ 456, 484)   19   0.33%  99.67%
# [ 484, 512)    9   0.16%  99.83%
# [ 512, 540)    7   0.12%  99.95%
# [ 540, 568]    3   0.05% 100.00%
#
# Attribute in nodes:
# 	778 : LongRunHighGrayLevelEmphasis [NUMERICAL]
# 	465 : HighGrayLevelRunEmphasis [NUMERICAL]
# 	435 : ShortRunHighGrayLevelEmphasis [NUMERICAL]
# 	413 : ShortRunLowGrayLevelEmphasis [NUMERICAL]
# 	366 : RunEntropy [NUMERICAL]
# 	339 : LowGrayLevelRunEmphasis [NUMERICAL]
# 	302 : GrayLevelNonUniformity [NUMERICAL]
# 	281 : LongRunLowGrayLevelEmphasis [NUMERICAL]
# 	280 : GrayLevelNonUniformityNormalized [NUMERICAL]
# 	271 : GrayLevelVariance [NUMERICAL]
# 	268 : RunVariance [NUMERICAL]
# 	258 : RunLengthNonUniformity [NUMERICAL]
# 	257 : LongRunEmphasis [NUMERICAL]
# 	248 : RunLengthNonUniformityNormalized [NUMERICAL]
# 	241 : ShortRunEmphasis [NUMERICAL]
# 	219 : RunPercentage [NUMERICAL]
#
# Attribute in nodes with depth <= 0:
# 	95 : LongRunHighGrayLevelEmphasis [NUMERICAL]
# 	59 : HighGrayLevelRunEmphasis [NUMERICAL]
# 	43 : ShortRunHighGrayLevelEmphasis [NUMERICAL]
# 	37 : ShortRunLowGrayLevelEmphasis [NUMERICAL]
# 	32 : LowGrayLevelRunEmphasis [NUMERICAL]
# 	16 : LongRunLowGrayLevelEmphasis [NUMERICAL]
# 	6 : RunVariance [NUMERICAL]
# 	6 : LongRunEmphasis [NUMERICAL]
# 	4 : RunPercentage [NUMERICAL]
# 	1 : RunLengthNonUniformity [NUMERICAL]
# 	1 : GrayLevelNonUniformityNormalized [NUMERICAL]
#
# Attribute in nodes with depth <= 1:
# 	270 : LongRunHighGrayLevelEmphasis [NUMERICAL]
# 	154 : HighGrayLevelRunEmphasis [NUMERICAL]
# 	111 : ShortRunHighGrayLevelEmphasis [NUMERICAL]
# 	102 : ShortRunLowGrayLevelEmphasis [NUMERICAL]
# 	82 : LowGrayLevelRunEmphasis [NUMERICAL]
# 	30 : LongRunLowGrayLevelEmphasis [NUMERICAL]
# 	25 : RunEntropy [NUMERICAL]
# 	18 : GrayLevelVariance [NUMERICAL]
# 	17 : RunPercentage [NUMERICAL]
# 	16 : RunVariance [NUMERICAL]
# 	15 : LongRunEmphasis [NUMERICAL]
# 	14 : RunLengthNonUniformityNormalized [NUMERICAL]
# 	12 : RunLengthNonUniformity [NUMERICAL]
# 	11 : GrayLevelNonUniformity [NUMERICAL]
# 	7 : ShortRunEmphasis [NUMERICAL]
# 	7 : GrayLevelNonUniformityNormalized [NUMERICAL]
#
# Attribute in nodes with depth <= 2:
# 	422 : LongRunHighGrayLevelEmphasis [NUMERICAL]
# 	242 : HighGrayLevelRunEmphasis [NUMERICAL]
# 	186 : ShortRunLowGrayLevelEmphasis [NUMERICAL]
# 	149 : LowGrayLevelRunEmphasis [NUMERICAL]
# 	147 : ShortRunHighGrayLevelEmphasis [NUMERICAL]
# 	84 : RunEntropy [NUMERICAL]
# 	83 : LongRunLowGrayLevelEmphasis [NUMERICAL]
# 	72 : GrayLevelVariance [NUMERICAL]
# 	63 : RunVariance [NUMERICAL]
# 	59 : LongRunEmphasis [NUMERICAL]
# 	56 : GrayLevelNonUniformity [NUMERICAL]
# 	55 : RunLengthNonUniformity [NUMERICAL]
# 	52 : RunLengthNonUniformityNormalized [NUMERICAL]
# 	49 : GrayLevelNonUniformityNormalized [NUMERICAL]
# 	45 : RunPercentage [NUMERICAL]
# 	39 : ShortRunEmphasis [NUMERICAL]
#
# Attribute in nodes with depth <= 3:
# 	528 : LongRunHighGrayLevelEmphasis [NUMERICAL]
# 	296 : HighGrayLevelRunEmphasis [NUMERICAL]
# 	250 : ShortRunLowGrayLevelEmphasis [NUMERICAL]
# 	232 : ShortRunHighGrayLevelEmphasis [NUMERICAL]
# 	192 : LowGrayLevelRunEmphasis [NUMERICAL]
# 	183 : RunEntropy [NUMERICAL]
# 	162 : LongRunLowGrayLevelEmphasis [NUMERICAL]
# 	131 : LongRunEmphasis [NUMERICAL]
# 	127 : GrayLevelNonUniformity [NUMERICAL]
# 	125 : RunLengthNonUniformity [NUMERICAL]
# 	124 : RunVariance [NUMERICAL]
# 	120 : GrayLevelVariance [NUMERICAL]
# 	120 : GrayLevelNonUniformityNormalized [NUMERICAL]
# 	114 : ShortRunEmphasis [NUMERICAL]
# 	111 : RunLengthNonUniformityNormalized [NUMERICAL]
# 	100 : RunPercentage [NUMERICAL]
#
# Attribute in nodes with depth <= 5:
# 	724 : LongRunHighGrayLevelEmphasis [NUMERICAL]
# 	413 : HighGrayLevelRunEmphasis [NUMERICAL]
# 	385 : ShortRunHighGrayLevelEmphasis [NUMERICAL]
# 	372 : ShortRunLowGrayLevelEmphasis [NUMERICAL]
# 	318 : RunEntropy [NUMERICAL]
# 	289 : LowGrayLevelRunEmphasis [NUMERICAL]
# 	270 : GrayLevelNonUniformity [NUMERICAL]
# 	243 : GrayLevelNonUniformityNormalized [NUMERICAL]
# 	238 : LongRunLowGrayLevelEmphasis [NUMERICAL]
# 	231 : RunLengthNonUniformity [NUMERICAL]
# 	225 : RunVariance [NUMERICAL]
# 	224 : GrayLevelVariance [NUMERICAL]
# 	219 : LongRunEmphasis [NUMERICAL]
# 	214 : RunLengthNonUniformityNormalized [NUMERICAL]
# 	207 : ShortRunEmphasis [NUMERICAL]
# 	190 : RunPercentage [NUMERICAL]
#
# Condition type in nodes:
# 	5421 : HigherCondition
# Condition type in nodes with depth <= 0:
# 	300 : HigherCondition
# Condition type in nodes with depth <= 1:
# 	891 : HigherCondition
# Condition type in nodes with depth <= 2:
# 	1803 : HigherCondition
# Condition type in nodes with depth <= 3:
# 	2915 : HigherCondition
# Condition type in nodes with depth <= 5:
# 	4762 : HigherCondition
# Node format: NOT_SET
#
# Training OOB:
# 	trees: 1, Out-of-bag evaluation: accuracy:0.870966 logloss:4.65086
# 	trees: 13, Out-of-bag evaluation: accuracy:0.887134 logloss:2.07897
# 	trees: 24, Out-of-bag evaluation: accuracy:0.917667 logloss:1.19364
# 	trees: 35, Out-of-bag evaluation: accuracy:0.906947 logloss:1.13002
# 	trees: 45, Out-of-bag evaluation: accuracy:0.901947 logloss:1.09608
# 	trees: 56, Out-of-bag evaluation: accuracy:0.905377 logloss:0.883588
# 	trees: 66, Out-of-bag evaluation: accuracy:0.911162 logloss:0.718256
# 	trees: 76, Out-of-bag evaluation: accuracy:0.907732 logloss:0.720396
# 	trees: 86, Out-of-bag evaluation: accuracy:0.921162 logloss:0.717553
# 	trees: 96, Out-of-bag evaluation: accuracy:0.920377 logloss:0.717011
# 	trees: 106, Out-of-bag evaluation: accuracy:0.915377 logloss:0.719043
# 	trees: 117, Out-of-bag evaluation: accuracy:0.915377 logloss:0.721221
# 	trees: 128, Out-of-bag evaluation: accuracy:0.915377 logloss:0.723823
# 	trees: 138, Out-of-bag evaluation: accuracy:0.915377 logloss:0.7252
# 	trees: 148, Out-of-bag evaluation: accuracy:0.915377 logloss:0.725743
# 	trees: 158, Out-of-bag evaluation: accuracy:0.916947 logloss:0.723455
# 	trees: 168, Out-of-bag evaluation: accuracy:0.916947 logloss:0.724282
# 	trees: 178, Out-of-bag evaluation: accuracy:0.917732 logloss:0.72479
# 	trees: 188, Out-of-bag evaluation: accuracy:0.916162 logloss:0.723001
# 	trees: 198, Out-of-bag evaluation: accuracy:0.916162 logloss:0.722212
# 	trees: 208, Out-of-bag evaluation: accuracy:0.912732 logloss:0.72248
# 	trees: 219, Out-of-bag evaluation: accuracy:0.916947 logloss:0.722696
# 	trees: 229, Out-of-bag evaluation: accuracy:0.917732 logloss:0.723835
# 	trees: 239, Out-of-bag evaluation: accuracy:0.916947 logloss:0.724127
# 	trees: 249, Out-of-bag evaluation: accuracy:0.917732 logloss:0.724033
# 	trees: 259, Out-of-bag evaluation: accuracy:0.911947 logloss:0.723588
# 	trees: 269, Out-of-bag evaluation: accuracy:0.906947 logloss:0.724137
# 	trees: 280, Out-of-bag evaluation: accuracy:0.912732 logloss:0.723729
# 	trees: 290, Out-of-bag evaluation: accuracy:0.912732 logloss:0.722527
# 	trees: 300, Out-of-bag evaluation: accuracy:0.911947 logloss:0.565522

# %%
# Model features
model.make_inspector().features()
# Out:
# ["GrayLevelNonUniformity" (1; #0),
#  "GrayLevelNonUniformityNormalized" (1; #1),
#  "GrayLevelVariance" (1; #2),
#  "HighGrayLevelRunEmphasis" (1; #3),
#  "LongRunEmphasis" (1; #4),
#  "LongRunHighGrayLevelEmphasis" (1; #5),
#  "LongRunLowGrayLevelEmphasis" (1; #6),
#  "LowGrayLevelRunEmphasis" (1; #7),
#  "RunEntropy" (1; #8),
#  "RunLengthNonUniformity" (1; #9),
#  "RunLengthNonUniformityNormalized" (1; #10),
#  "RunPercentage" (1; #11),
#  "RunVariance" (1; #12),
#  "ShortRunEmphasis" (1; #13),
#  "ShortRunHighGrayLevelEmphasis" (1; #14),
#  "ShortRunLowGrayLevelEmphasis" (1; #15)]

# %%
# Feature importance
model.make_inspector().variable_importances()
# Out:
# {'INV_MEAN_MIN_DEPTH': [("LongRunHighGrayLevelEmphasis" (1; #5),
#    0.3207322206812681),
#   ("HighGrayLevelRunEmphasis" (1; #3), 0.24974468926572635),
#   ("ShortRunHighGrayLevelEmphasis" (1; #14), 0.2195743507217183),
#   ("ShortRunLowGrayLevelEmphasis" (1; #15), 0.21280447209830625),
#   ("LowGrayLevelRunEmphasis" (1; #7), 0.20598045404493168),
#   ("LongRunLowGrayLevelEmphasis" (1; #6), 0.1892168597986709),
#   ("RunEntropy" (1; #8), 0.18455675142846625),
#   ("LongRunEmphasis" (1; #4), 0.18237444548849582),
#   ("RunVariance" (1; #12), 0.18178789697208003),
#   ("RunLengthNonUniformity" (1; #9), 0.18116523485998767),
#   ("RunPercentage" (1; #11), 0.17983734110049843),
#   ("GrayLevelNonUniformity" (1; #0), 0.1779769650109943),
#   ("RunLengthNonUniformityNormalized" (1; #10), 0.1777113996028386),
#   ("GrayLevelVariance" (1; #2), 0.17758932925935586),
#   ("ShortRunEmphasis" (1; #13), 0.176728645647467),
#   ("GrayLevelNonUniformityNormalized" (1; #1), 0.17634753206254133)],
#  'SUM_SCORE': [("LongRunHighGrayLevelEmphasis" (1; #5), 47040.951294008984),
#   ("HighGrayLevelRunEmphasis" (1; #3), 25359.156235604263),
#   ("ShortRunHighGrayLevelEmphasis" (1; #14), 16474.038304778333),
#   ("ShortRunLowGrayLevelEmphasis" (1; #15), 12954.425609295793),
#   ("LowGrayLevelRunEmphasis" (1; #7), 10900.160194798265),
#   ("LongRunLowGrayLevelEmphasis" (1; #6), 5522.349873076044),
#   ("RunEntropy" (1; #8), 3775.153046202216),
#   ("RunVariance" (1; #12), 2737.0208262198676),
#   ("GrayLevelNonUniformity" (1; #0), 2519.913218807149),
#   ("LongRunEmphasis" (1; #4), 2480.7769495182997),
#   ("RunLengthNonUniformity" (1; #9), 2466.6105825569803),
#   ("GrayLevelNonUniformityNormalized" (1; #1), 2332.1987028620097),
#   ("GrayLevelVariance" (1; #2), 2254.765570223736),
#   ("RunPercentage" (1; #11), 2111.518300798194),
#   ("ShortRunEmphasis" (1; #13), 1962.888039540014),
#   ("RunLengthNonUniformityNormalized" (1; #10), 1945.1888294094374)],
#  'NUM_AS_ROOT': [("LongRunHighGrayLevelEmphasis" (1; #5), 95.0),
#   ("HighGrayLevelRunEmphasis" (1; #3), 59.0),
#   ("ShortRunHighGrayLevelEmphasis" (1; #14), 43.0),
#   ("ShortRunLowGrayLevelEmphasis" (1; #15), 37.0),
#   ("LowGrayLevelRunEmphasis" (1; #7), 32.0),
#   ("LongRunLowGrayLevelEmphasis" (1; #6), 16.0),
#   ("LongRunEmphasis" (1; #4), 6.0),
#   ("RunVariance" (1; #12), 6.0),
#   ("RunPercentage" (1; #11), 4.0),
#   ("GrayLevelNonUniformityNormalized" (1; #1), 1.0),
#   ("RunLengthNonUniformity" (1; #9), 1.0)],
#  'NUM_NODES': [("LongRunHighGrayLevelEmphasis" (1; #5), 778.0),
#   ("HighGrayLevelRunEmphasis" (1; #3), 465.0),
#   ("ShortRunHighGrayLevelEmphasis" (1; #14), 435.0),
#   ("ShortRunLowGrayLevelEmphasis" (1; #15), 413.0),
#   ("RunEntropy" (1; #8), 366.0),
#   ("LowGrayLevelRunEmphasis" (1; #7), 339.0),
#   ("GrayLevelNonUniformity" (1; #0), 302.0),
#   ("LongRunLowGrayLevelEmphasis" (1; #6), 281.0),
#   ("GrayLevelNonUniformityNormalized" (1; #1), 280.0),
#   ("GrayLevelVariance" (1; #2), 271.0),
#   ("RunVariance" (1; #12), 268.0),
#   ("RunLengthNonUniformity" (1; #9), 258.0),
#   ("LongRunEmphasis" (1; #4), 257.0),
#   ("RunLengthNonUniformityNormalized" (1; #10), 248.0),
#   ("ShortRunEmphasis" (1; #13), 241.0),
#   ("RunPercentage" (1; #11), 219.0)]}

# %%
# Model self evaluation
model.make_inspector().evaluation()
# Out:
# Evaluation(num_examples=737, accuracy=0.9119466253793276, loss=0.5655222429480598, rmse=None, ndcg=None, aucs=None, auuc=None, qini=None)

# %%
logs = model.make_inspector().training_logs()

plt.figure(figsize=(12, 4))
plt.subplot(1, 2, 1)
plt.plot([log.num_trees for log in logs], [log.evaluation.accuracy for log in logs])
plt.xlabel("Number of trees")
plt.ylabel("Accuracy (out-of-bag)")
plt.subplot(1, 2, 2)
plt.plot([log.num_trees for log in logs], [log.evaluation.loss for log in logs])
plt.xlabel("Number of trees")
plt.ylabel("Logloss (out-of-bag)")
plt.show()

# %% [markdown]
# Calculate the score of our hold-out validation dataset

# %%
predictions = model.predict(val_ds)
y_true      = validation_data["label"]

from sklearn.metrics import roc_auc_score
ROC_AUC = roc_auc_score(y_true, predictions)
print("The ROC AUC score is %.5f" % ROC_AUC )
# Out:
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 67ms/step
# The ROC AUC score is 0.96703

# %%
# Compute binary classification metrics with sklearn
import numpy as np
from sklearn.metrics import (
    accuracy_score,
    precision_score,
    recall_score,
    f1_score,
    roc_auc_score,
    average_precision_score,
    confusion_matrix,
    classification_report,
    matthews_corrcoef,
    log_loss,
    brier_score_loss,
)

# Get predictions (probabilities or class labels)
preds = model.predict(test_ds)
# If model outputs probabilities, convert to labels by threshold 0.5
if preds.ndim == 2:
    # For TFDF classification, preds may be class probabilities with shape (N, 2)
    if preds.shape[1] == 2:
        pos_probs = preds[:, 1]
    else:
        # If single-probability column (positive class)
        pos_probs = preds[:, -1]
    y_pred = (pos_probs >= 0.5).astype(int)
else:
    # Already class labels
    y_pred = preds.astype(int)
    pos_probs = None

# Ground truth labels (must be 0/1 integers)
y_true = test_data["label"].astype(int).to_numpy()

# Core metrics
metrics = {}
metrics["accuracy"] = accuracy_score(y_true, y_pred)
metrics["precision"] = precision_score(y_true, y_pred, zero_division=0)
metrics["recall"] = recall_score(y_true, y_pred, zero_division=0)
metrics["f1"] = f1_score(y_true, y_pred, zero_division=0)
metrics["mcc"] = matthews_corrcoef(y_true, y_pred)

# Probabilistic metrics (only if we have probabilities)
if pos_probs is not None:
    metrics["roc_auc"] = roc_auc_score(y_true, pos_probs)
    metrics["pr_auc"] = average_precision_score(y_true, pos_probs)
    metrics["log_loss"] = log_loss(y_true, pos_probs, labels=[0,1])
    metrics["brier_score"] = brier_score_loss(y_true, pos_probs)

# Confusion matrix and detailed report
cm = confusion_matrix(y_true, y_pred, labels=[0,1])
report = classification_report(y_true, y_pred, digits=4)

print("Sklearn binary metrics:")
for k, v in metrics.items():
    print(f"{k}: {v:.4f}")
print("\nConfusion matrix:\n", cm)
print("\nClassification report:\n", report)
# Out:
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 72ms/step
# Sklearn binary metrics:
# accuracy: 0.9670
# precision: 0.9167
# recall: 0.8148
# f1: 0.8627
# mcc: 0.8459
# roc_auc: 0.9943
# pr_auc: 0.9648
# log_loss: 0.0847
# brier_score: 0.0228
#
# Confusion matrix:
#  [[183   2]
#  [  5  22]]
#
# Classification report:
#                precision    recall  f1-score   support
#
#            0     0.9734    0.9892    0.9812       185
#            1     0.9167    0.8148    0.8627        27
#
#     accuracy                         0.9670       212
#    macro avg     0.9450    0.9020    0.9220       212
# weighted avg     0.9662    0.9670    0.9661       212
