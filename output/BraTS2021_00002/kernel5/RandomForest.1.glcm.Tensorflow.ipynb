# %%
# Import packages and modules
import numpy  as np
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow_decision_forests as tfdf

from sklearn.model_selection import train_test_split
# Out:
# 2026-08-13 04:26:25.404839: I tensorflow/core/util/port.cc:113] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2026-08-13 04:26:25.784042: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2026-08-13 04:26:30.828916: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
# Check the version of TensorFlow Decision Forests
print("Found TensorFlow Decision Forests v" + tfdf.__version__)
# Out:
# Found TensorFlow Decision Forests v1.9.1

# %%
datasetPath = 'dataset/firstorder/kernel5/dataset.csv'

# %%
# Parameters
datasetPath = "dataset/glcm/kernel5/1.dataset.csv"

# %%
# train/validation/test = 70/10/20
dataset = pd.read_csv(datasetPath)

train_data, temp_data = train_test_split(dataset, test_size=0.3, random_state=42)
validation_data, test_data = train_test_split(temp_data, test_size=2/3, random_state=42)

# %%
from sklearn.utils.class_weight import compute_class_weight

# tinh class weight tren tap train
classes = np.array([0, 1])
weights = compute_class_weight(class_weight="balanced", classes=classes, y=train_data["label"])
class_weight = {0: weights[0], 1: weights[1]}

# gan sample_weight cho tung dong
train_data["sample_weight"] = train_data["label"].map(class_weight)
validation_data["sample_weight"] = validation_data["label"].map(class_weight)
test_data["sample_weight"] = test_data["label"].map(class_weight)

# Convert the dataset into a TensorFlow dataset.
train_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    train_data, label="label", weight="sample_weight"
)         
val_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    validation_data, label="label", weight="sample_weight"
)
test_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    test_data, label="label", weight="sample_weight"
)
# Out:
# 2026-08-13 04:26:44.913900: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:984] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2026-08-13 04:26:44.915816: W tensorflow/core/common_runtime/gpu/gpu_device.cc:2251] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...

# %%
import keras

# %%
# %%time

# Train a Random Forest model.
model = tfdf.keras.RandomForestModel()

# Add evaluation metrics
model.compile(
    metrics=["accuracy"]
)
model.fit(x=train_ds)

# # Train a Gradient Boosted Trees model.
# model = tfdf.keras.GradientBoostedTreesModel(num_trees=1500)
# model.fit(train_ds)
# Out:
# Use /tmp/tmpzhnfe22k as temporary training directory
# Reading training dataset...
# Training dataset read in 0:00:02.744265. Found 737 examples.
# Training model...
# Model trained in 0:00:00.068789
# Compiling model...
# [INFO 26-08-13 04:26:47.9129 UTC kernel.cc:1233] Loading model from path /tmp/tmpzhnfe22k/model/ with prefix 0125c58f4527442e
# [INFO 26-08-13 04:26:47.9266 UTC decision_forest.cc:734] Model loaded with 300 root(s), 10350 node(s), and 24 input feature(s).
# [INFO 26-08-13 04:26:47.9266 UTC abstract_model.cc:1362] Engine "RandomForestOptPred" built
# [INFO 26-08-13 04:26:47.9266 UTC kernel.cc:1061] Use fast generic engine
# Model compiled.
# CPU times: user 5.75 s, sys: 121 ms, total: 5.87 s
# Wall time: 6.19 s

# %%
# Evaluate the model
evaluate = model.evaluate(val_ds, return_dict=True)
print()

for name, value in evaluate.items():
    print(f"{name}: {value:.4f}")
# Out:
# WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 1/1 [==============================] - ETA: 0s - loss: 0.0000e+00 - accuracy: 0.9905
# 1/1 [==============================] - 3s 3s/step - loss: 0.0000e+00 - accuracy: 0.9905
# loss: 0.0000
# accuracy: 0.9905

# %%
# Model Summary
model.summary()
# Out:
# Model: "random_forest_model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
# =================================================================
# Total params: 1 (1.00 Byte)
# Trainable params: 0 (0.00 Byte)
# Non-trainable params: 1 (1.00 Byte)
# _________________________________________________________________
# Type: "RANDOM_FOREST"
# Task: CLASSIFICATION
# Label: "__LABEL"
#
# Input Features (24):
# 	Autocorrelation
# 	ClusterProminence
# 	ClusterShade
# 	ClusterTendency
# 	Contrast
# 	Correlation
# 	DifferenceAverage
# 	DifferenceEntropy
# 	DifferenceVariance
# 	Id
# 	Idm
# 	Idmn
# 	Idn
# 	Imc1
# 	Imc2
# 	InverseVariance
# 	JointAverage
# 	JointEnergy
# 	JointEntropy
# 	MCC
# 	MaximumProbability
# 	SumAverage
# 	SumEntropy
# 	SumSquares
#
# Trained with weights
#
# Variable Importance: INV_MEAN_MIN_DEPTH:
#     1.    "Autocorrelation"  0.263105 ################
#     2.       "JointAverage"  0.251201 #############
#     3.         "SumAverage"  0.243535 ############
#     4.               "Imc1"  0.202841 #####
#     5.                "MCC"  0.196331 ####
#     6.        "Correlation"  0.194135 ###
#     7.    "InverseVariance"  0.192950 ###
#     8. "MaximumProbability"  0.189321 ###
#     9.                "Idm"  0.184019 ##
#    10.               "Imc2"  0.180836 #
#    11.                 "Id"  0.179658 #
#    12.        "JointEnergy"  0.178804 #
#    13.       "ClusterShade"  0.177397 #
#    14.  "DifferenceEntropy"  0.176677
#    15.                "Idn"  0.174711
#    16.         "SumEntropy"  0.173822
#    17. "DifferenceVariance"  0.173730
#    18.               "Idmn"  0.173198
#    19.  "DifferenceAverage"  0.173017
#    20.           "Contrast"  0.172242
#    21.       "JointEntropy"  0.172007
#    22.  "ClusterProminence"  0.171252
#    23.         "SumSquares"  0.171233
#    24.    "ClusterTendency"  0.171172
#
# Variable Importance: NUM_AS_ROOT:
#     1.    "Autocorrelation" 73.000000 ################
#     2.       "JointAverage" 64.000000 ##############
#     3.         "SumAverage" 49.000000 ##########
#     4.                "MCC" 25.000000 #####
#     5.               "Imc1" 20.000000 ####
#     6.        "Correlation" 16.000000 ###
#     7. "MaximumProbability" 15.000000 ###
#     8.    "InverseVariance" 14.000000 ##
#     9.               "Imc2"  5.000000
#    10.  "DifferenceEntropy"  4.000000
#    11.  "DifferenceAverage"  3.000000
#    12.               "Idmn"  3.000000
#    13.        "JointEnergy"  3.000000
#    14.       "ClusterShade"  2.000000
#    15.           "Contrast"  1.000000
#    16.                 "Id"  1.000000
#    17.                "Idm"  1.000000
#    18.                "Idn"  1.000000
#
# Variable Importance: NUM_NODES:
#     1.         "SumAverage" 483.000000 ################
#     2.    "Autocorrelation" 477.000000 ###############
#     3.       "JointAverage" 439.000000 ##############
#     4.               "Imc1" 271.000000 #######
#     5.        "Correlation" 246.000000 ######
#     6.    "InverseVariance" 240.000000 #####
#     7. "MaximumProbability" 232.000000 #####
#     8.       "ClusterShade" 223.000000 #####
#     9.                "MCC" 217.000000 ####
#    10.                "Idm" 214.000000 ####
#    11.               "Imc2" 207.000000 ####
#    12.                 "Id" 203.000000 ####
#    13.        "JointEnergy" 179.000000 ###
#    14. "DifferenceVariance" 165.000000 ##
#    15.         "SumEntropy" 145.000000 #
#    16.       "JointEntropy" 140.000000 #
#    17.  "DifferenceEntropy" 132.000000 #
#    18.               "Idmn" 130.000000 #
#    19.                "Idn" 122.000000
#    20.           "Contrast" 120.000000
#    21.  "DifferenceAverage" 117.000000
#    22.  "ClusterProminence" 110.000000
#    23.         "SumSquares" 110.000000
#    24.    "ClusterTendency" 103.000000
#
# Variable Importance: SUM_SCORE:
#     1.    "Autocorrelation" 35789.436999 ################
#     2.       "JointAverage" 31314.478270 #############
#     3.         "SumAverage" 27804.031436 ############
#     4.               "Imc1" 5249.574202 #
#     5.                "MCC" 5054.643893 #
#     6.        "Correlation" 4752.999865 #
#     7.    "InverseVariance" 4274.416557 #
#     8. "MaximumProbability" 3468.976777 #
#     9.               "Imc2" 3064.037752
#    10.                "Idm" 2829.201780
#    11.                 "Id" 2293.287819
#    12. "DifferenceVariance" 2006.941426
#    13.       "ClusterShade" 1961.442530
#    14.        "JointEnergy" 1851.554735
#    15.  "DifferenceEntropy" 1621.945347
#    16.               "Idmn" 1373.366168
#    17.           "Contrast" 1278.564179
#    18.         "SumEntropy" 1240.138461
#    19.                "Idn" 1239.353849
#    20.  "DifferenceAverage" 1169.493012
#    21.       "JointEntropy" 1055.342805
#    22.         "SumSquares" 1013.310885
#    23.  "ClusterProminence" 978.874823
#    24.    "ClusterTendency" 903.689112
#
#
#
# Winner takes all: true
# Out-of-bag evaluation: accuracy:0.913092 logloss:0.232477
# Number of trees: 300
# Total number of nodes: 10350
#
# Number of nodes by tree:
# Count: 300 Average: 34.5 StdDev: 4.5111
# Min: 23 Max: 51 Ignored: 0
# ----------------------------------------------
# [ 23, 24)  2   0.67%   0.67%
# [ 24, 25)  0   0.00%   0.67%
# [ 25, 27)  5   1.67%   2.33% #
# [ 27, 28) 15   5.00%   7.33% ###
# [ 28, 30) 27   9.00%  16.33% #####
# [ 30, 31)  0   0.00%  16.33%
# [ 31, 33) 37  12.33%  28.67% #######
# [ 33, 34) 51  17.00%  45.67% ##########
# [ 34, 36) 49  16.33%  62.00% #########
# [ 36, 37)  0   0.00%  62.00%
# [ 37, 38) 52  17.33%  79.33% ##########
# [ 38, 40) 38  12.67%  92.00% #######
# [ 40, 41)  0   0.00%  92.00%
# [ 41, 43)  9   3.00%  95.00% ##
# [ 43, 44)  9   3.00%  98.00% ##
# [ 44, 46)  3   1.00%  99.00% #
# [ 46, 47)  0   0.00%  99.00%
# [ 47, 49)  0   0.00%  99.00%
# [ 49, 50)  2   0.67%  99.67%
# [ 50, 51]  1   0.33% 100.00%
#
# Depth by leafs:
# Count: 5325 Average: 5.03568 StdDev: 1.72424
# Min: 1 Max: 11 Ignored: 0
# ----------------------------------------------
# [  1,  2)   25   0.47%   0.47%
# [  2,  3)  272   5.11%   5.58% ##
# [  3,  4)  733  13.77%  19.34% ######
# [  4,  5) 1122  21.07%  40.41% ##########
# [  5,  6) 1179  22.14%  62.55% ##########
# [  6,  7)  954  17.92%  80.47% ########
# [  7,  8)  587  11.02%  91.49% #####
# [  8,  9)  292   5.48%  96.98% ##
# [  9, 10)  123   2.31%  99.29% #
# [ 10, 11)   30   0.56%  99.85%
# [ 11, 11]    8   0.15% 100.00%
#
# Number of training obs by leaf:
# Count: 5325 Average: 41.5211 StdDev: 88.0191
# Min: 5 Max: 584 Ignored: 0
# ----------------------------------------------
# [   5,  34) 4231  79.46%  79.46% ##########
# [  34,  63)  425   7.98%  87.44% #
# [  63,  92)   82   1.54%  88.98%
# [  92, 121)   57   1.07%  90.05%
# [ 121, 150)   50   0.94%  90.99%
# [ 150, 179)   68   1.28%  92.26%
# [ 179, 208)   60   1.13%  93.39%
# [ 208, 237)   53   1.00%  94.38%
# [ 237, 266)   35   0.66%  95.04%
# [ 266, 295)   36   0.68%  95.72%
# [ 295, 324)   38   0.71%  96.43%
# [ 324, 353)   51   0.96%  97.39%
# [ 353, 382)   38   0.71%  98.10%
# [ 382, 411)   33   0.62%  98.72%
# [ 411, 440)   16   0.30%  99.02%
# [ 440, 469)   19   0.36%  99.38%
# [ 469, 498)   11   0.21%  99.59%
# [ 498, 527)    8   0.15%  99.74%
# [ 527, 556)   13   0.24%  99.98%
# [ 556, 584]    1   0.02% 100.00%
#
# Attribute in nodes:
# 	483 : SumAverage [NUMERICAL]
# 	477 : Autocorrelation [NUMERICAL]
# 	439 : JointAverage [NUMERICAL]
# 	271 : Imc1 [NUMERICAL]
# 	246 : Correlation [NUMERICAL]
# 	240 : InverseVariance [NUMERICAL]
# 	232 : MaximumProbability [NUMERICAL]
# 	223 : ClusterShade [NUMERICAL]
# 	217 : MCC [NUMERICAL]
# 	214 : Idm [NUMERICAL]
# 	207 : Imc2 [NUMERICAL]
# 	203 : Id [NUMERICAL]
# 	179 : JointEnergy [NUMERICAL]
# 	165 : DifferenceVariance [NUMERICAL]
# 	145 : SumEntropy [NUMERICAL]
# 	140 : JointEntropy [NUMERICAL]
# 	132 : DifferenceEntropy [NUMERICAL]
# 	130 : Idmn [NUMERICAL]
# 	122 : Idn [NUMERICAL]
# 	120 : Contrast [NUMERICAL]
# 	117 : DifferenceAverage [NUMERICAL]
# 	110 : SumSquares [NUMERICAL]
# 	110 : ClusterProminence [NUMERICAL]
# 	103 : ClusterTendency [NUMERICAL]
#
# Attribute in nodes with depth <= 0:
# 	73 : Autocorrelation [NUMERICAL]
# 	64 : JointAverage [NUMERICAL]
# 	49 : SumAverage [NUMERICAL]
# 	25 : MCC [NUMERICAL]
# 	20 : Imc1 [NUMERICAL]
# 	16 : Correlation [NUMERICAL]
# 	15 : MaximumProbability [NUMERICAL]
# 	14 : InverseVariance [NUMERICAL]
# 	5 : Imc2 [NUMERICAL]
# 	4 : DifferenceEntropy [NUMERICAL]
# 	3 : JointEnergy [NUMERICAL]
# 	3 : Idmn [NUMERICAL]
# 	3 : DifferenceAverage [NUMERICAL]
# 	2 : ClusterShade [NUMERICAL]
# 	1 : Idn [NUMERICAL]
# 	1 : Idm [NUMERICAL]
# 	1 : Id [NUMERICAL]
# 	1 : Contrast [NUMERICAL]
#
# Attribute in nodes with depth <= 1:
# 	179 : Autocorrelation [NUMERICAL]
# 	158 : JointAverage [NUMERICAL]
# 	148 : SumAverage [NUMERICAL]
# 	66 : Imc1 [NUMERICAL]
# 	56 : Correlation [NUMERICAL]
# 	54 : MCC [NUMERICAL]
# 	37 : InverseVariance [NUMERICAL]
# 	25 : Imc2 [NUMERICAL]
# 	23 : MaximumProbability [NUMERICAL]
# 	17 : Idm [NUMERICAL]
# 	13 : Idmn [NUMERICAL]
# 	13 : DifferenceVariance [NUMERICAL]
# 	12 : DifferenceEntropy [NUMERICAL]
# 	11 : JointEnergy [NUMERICAL]
# 	11 : Contrast [NUMERICAL]
# 	11 : ClusterShade [NUMERICAL]
# 	10 : Id [NUMERICAL]
# 	7 : DifferenceAverage [NUMERICAL]
# 	6 : Idn [NUMERICAL]
# 	5 : SumEntropy [NUMERICAL]
# 	5 : ClusterProminence [NUMERICAL]
# 	4 : SumSquares [NUMERICAL]
# 	2 : JointEntropy [NUMERICAL]
# 	2 : ClusterTendency [NUMERICAL]
#
# Attribute in nodes with depth <= 2:
# 	256 : Autocorrelation [NUMERICAL]
# 	249 : JointAverage [NUMERICAL]
# 	243 : SumAverage [NUMERICAL]
# 	100 : Imc1 [NUMERICAL]
# 	99 : MCC [NUMERICAL]
# 	98 : Correlation [NUMERICAL]
# 	81 : InverseVariance [NUMERICAL]
# 	71 : MaximumProbability [NUMERICAL]
# 	70 : Idm [NUMERICAL]
# 	65 : Imc2 [NUMERICAL]
# 	62 : Id [NUMERICAL]
# 	43 : DifferenceEntropy [NUMERICAL]
# 	41 : ClusterShade [NUMERICAL]
# 	39 : DifferenceVariance [NUMERICAL]
# 	31 : JointEnergy [NUMERICAL]
# 	29 : Idmn [NUMERICAL]
# 	29 : DifferenceAverage [NUMERICAL]
# 	28 : Idn [NUMERICAL]
# 	26 : SumEntropy [NUMERICAL]
# 	25 : ClusterProminence [NUMERICAL]
# 	22 : Contrast [NUMERICAL]
# 	18 : SumSquares [NUMERICAL]
# 	15 : ClusterTendency [NUMERICAL]
# 	13 : JointEntropy [NUMERICAL]
#
# Attribute in nodes with depth <= 3:
# 	347 : Autocorrelation [NUMERICAL]
# 	328 : SumAverage [NUMERICAL]
# 	317 : JointAverage [NUMERICAL]
# 	151 : Imc1 [NUMERICAL]
# 	146 : MCC [NUMERICAL]
# 	141 : Correlation [NUMERICAL]
# 	131 : InverseVariance [NUMERICAL]
# 	122 : Idm [NUMERICAL]
# 	109 : Imc2 [NUMERICAL]
# 	106 : MaximumProbability [NUMERICAL]
# 	104 : ClusterShade [NUMERICAL]
# 	102 : Id [NUMERICAL]
# 	72 : JointEnergy [NUMERICAL]
# 	72 : DifferenceVariance [NUMERICAL]
# 	72 : DifferenceEntropy [NUMERICAL]
# 	63 : Idn [NUMERICAL]
# 	58 : SumEntropy [NUMERICAL]
# 	58 : Idmn [NUMERICAL]
# 	58 : DifferenceAverage [NUMERICAL]
# 	57 : JointEntropy [NUMERICAL]
# 	47 : ClusterProminence [NUMERICAL]
# 	42 : Contrast [NUMERICAL]
# 	37 : ClusterTendency [NUMERICAL]
# 	36 : SumSquares [NUMERICAL]
#
# Attribute in nodes with depth <= 5:
# 	446 : Autocorrelation [NUMERICAL]
# 	440 : SumAverage [NUMERICAL]
# 	404 : JointAverage [NUMERICAL]
# 	233 : Imc1 [NUMERICAL]
# 	215 : Correlation [NUMERICAL]
# 	213 : InverseVariance [NUMERICAL]
# 	200 : MaximumProbability [NUMERICAL]
# 	195 : MCC [NUMERICAL]
# 	190 : Idm [NUMERICAL]
# 	186 : Imc2 [NUMERICAL]
# 	184 : ClusterShade [NUMERICAL]
# 	170 : Id [NUMERICAL]
# 	143 : JointEnergy [NUMERICAL]
# 	135 : DifferenceVariance [NUMERICAL]
# 	120 : SumEntropy [NUMERICAL]
# 	115 : DifferenceEntropy [NUMERICAL]
# 	110 : JointEntropy [NUMERICAL]
# 	110 : Idmn [NUMERICAL]
# 	104 : Idn [NUMERICAL]
# 	102 : DifferenceAverage [NUMERICAL]
# 	93 : Contrast [NUMERICAL]
# 	89 : ClusterProminence [NUMERICAL]
# 	87 : SumSquares [NUMERICAL]
# 	85 : ClusterTendency [NUMERICAL]
#
# Condition type in nodes:
# 	5025 : HigherCondition
# Condition type in nodes with depth <= 0:
# 	300 : HigherCondition
# Condition type in nodes with depth <= 1:
# 	875 : HigherCondition
# Condition type in nodes with depth <= 2:
# 	1753 : HigherCondition
# Condition type in nodes with depth <= 3:
# 	2776 : HigherCondition
# Condition type in nodes with depth <= 5:
# 	4369 : HigherCondition
# Node format: NOT_SET
#
# Training OOB:
# 	trees: 1, Out-of-bag evaluation: accuracy:0.813505 logloss:6.72194
# 	trees: 13, Out-of-bag evaluation: accuracy:0.895674 logloss:2.46167
# 	trees: 23, Out-of-bag evaluation: accuracy:0.901329 logloss:0.674916
# 	trees: 33, Out-of-bag evaluation: accuracy:0.911544 logloss:0.457953
# 	trees: 44, Out-of-bag evaluation: accuracy:0.89506 logloss:0.457387
# 	trees: 55, Out-of-bag evaluation: accuracy:0.899781 logloss:0.457353
# 	trees: 65, Out-of-bag evaluation: accuracy:0.899781 logloss:0.431749
# 	trees: 75, Out-of-bag evaluation: accuracy:0.901329 logloss:0.432262
# 	trees: 85, Out-of-bag evaluation: accuracy:0.906823 logloss:0.428093
# 	trees: 95, Out-of-bag evaluation: accuracy:0.905275 logloss:0.404651
# 	trees: 105, Out-of-bag evaluation: accuracy:0.905275 logloss:0.400675
# 	trees: 116, Out-of-bag evaluation: accuracy:0.905275 logloss:0.402158
# 	trees: 126, Out-of-bag evaluation: accuracy:0.909996 logloss:0.403318
# 	trees: 136, Out-of-bag evaluation: accuracy:0.905275 logloss:0.402161
# 	trees: 146, Out-of-bag evaluation: accuracy:0.905275 logloss:0.400838
# 	trees: 157, Out-of-bag evaluation: accuracy:0.905275 logloss:0.402735
# 	trees: 167, Out-of-bag evaluation: accuracy:0.906049 logloss:0.397591
# 	trees: 177, Out-of-bag evaluation: accuracy:0.905275 logloss:0.398054
# 	trees: 187, Out-of-bag evaluation: accuracy:0.905275 logloss:0.223414
# 	trees: 197, Out-of-bag evaluation: accuracy:0.905275 logloss:0.224829
# 	trees: 207, Out-of-bag evaluation: accuracy:0.905275 logloss:0.226237
# 	trees: 217, Out-of-bag evaluation: accuracy:0.911544 logloss:0.227316
# 	trees: 228, Out-of-bag evaluation: accuracy:0.913092 logloss:0.227948
# 	trees: 238, Out-of-bag evaluation: accuracy:0.906823 logloss:0.229
# 	trees: 248, Out-of-bag evaluation: accuracy:0.912318 logloss:0.230692
# 	trees: 258, Out-of-bag evaluation: accuracy:0.912318 logloss:0.231925
# 	trees: 268, Out-of-bag evaluation: accuracy:0.912318 logloss:0.232484
# 	trees: 278, Out-of-bag evaluation: accuracy:0.912318 logloss:0.232917
# 	trees: 289, Out-of-bag evaluation: accuracy:0.912318 logloss:0.231805
# 	trees: 299, Out-of-bag evaluation: accuracy:0.913092 logloss:0.232523
# 	trees: 300, Out-of-bag evaluation: accuracy:0.913092 logloss:0.232477

# %%
# Model features
model.make_inspector().features()
# Out:
# ["Autocorrelation" (1; #0),
#  "ClusterProminence" (1; #1),
#  "ClusterShade" (1; #2),
#  "ClusterTendency" (1; #3),
#  "Contrast" (1; #4),
#  "Correlation" (1; #5),
#  "DifferenceAverage" (1; #6),
#  "DifferenceEntropy" (1; #7),
#  "DifferenceVariance" (1; #8),
#  "Id" (1; #9),
#  "Idm" (1; #10),
#  "Idmn" (1; #11),
#  "Idn" (1; #12),
#  "Imc1" (1; #13),
#  "Imc2" (1; #14),
#  "InverseVariance" (1; #15),
#  "JointAverage" (1; #16),
#  "JointEnergy" (1; #17),
#  "JointEntropy" (1; #18),
#  "MCC" (1; #19),
#  "MaximumProbability" (1; #20),
#  "SumAverage" (1; #21),
#  "SumEntropy" (1; #22),
#  "SumSquares" (1; #23)]

# %%
# Feature importance
model.make_inspector().variable_importances()
# Out:
# {'INV_MEAN_MIN_DEPTH': [("Autocorrelation" (1; #0), 0.26310528774787423),
#   ("JointAverage" (1; #16), 0.2512011502713501),
#   ("SumAverage" (1; #21), 0.2435353366168989),
#   ("Imc1" (1; #13), 0.2028405717181237),
#   ("MCC" (1; #19), 0.1963314712820572),
#   ("Correlation" (1; #5), 0.1941349062009465),
#   ("InverseVariance" (1; #15), 0.19294993516417297),
#   ("MaximumProbability" (1; #20), 0.18932131867427723),
#   ("Idm" (1; #10), 0.1840191366334712),
#   ("Imc2" (1; #14), 0.18083634353904718),
#   ("Id" (1; #9), 0.17965750001340938),
#   ("JointEnergy" (1; #17), 0.1788043441647163),
#   ("ClusterShade" (1; #2), 0.17739689322427213),
#   ("DifferenceEntropy" (1; #7), 0.17667663185196328),
#   ("Idn" (1; #12), 0.1747107389979734),
#   ("SumEntropy" (1; #22), 0.17382249186605184),
#   ("DifferenceVariance" (1; #8), 0.17373043856922601),
#   ("Idmn" (1; #11), 0.17319817601891782),
#   ("DifferenceAverage" (1; #6), 0.1730168554858547),
#   ("Contrast" (1; #4), 0.1722418692318439),
#   ("JointEntropy" (1; #18), 0.17200729517198654),
#   ("ClusterProminence" (1; #1), 0.17125178214460385),
#   ("SumSquares" (1; #23), 0.17123279073477063),
#   ("ClusterTendency" (1; #3), 0.1711724621258073)],
#  'NUM_AS_ROOT': [("Autocorrelation" (1; #0), 73.0),
#   ("JointAverage" (1; #16), 64.0),
#   ("SumAverage" (1; #21), 49.0),
#   ("MCC" (1; #19), 25.0),
#   ("Imc1" (1; #13), 20.0),
#   ("Correlation" (1; #5), 16.0),
#   ("MaximumProbability" (1; #20), 15.0),
#   ("InverseVariance" (1; #15), 14.0),
#   ("Imc2" (1; #14), 5.0),
#   ("DifferenceEntropy" (1; #7), 4.0),
#   ("DifferenceAverage" (1; #6), 3.0),
#   ("Idmn" (1; #11), 3.0),
#   ("JointEnergy" (1; #17), 3.0),
#   ("ClusterShade" (1; #2), 2.0),
#   ("Contrast" (1; #4), 1.0),
#   ("Id" (1; #9), 1.0),
#   ("Idm" (1; #10), 1.0),
#   ("Idn" (1; #12), 1.0)],
#  'SUM_SCORE': [("Autocorrelation" (1; #0), 35789.43699887328),
#   ("JointAverage" (1; #16), 31314.478269623836),
#   ("SumAverage" (1; #21), 27804.031435894016),
#   ("Imc1" (1; #13), 5249.574202354702),
#   ("MCC" (1; #19), 5054.643893429508),
#   ("Correlation" (1; #5), 4752.999864900759),
#   ("InverseVariance" (1; #15), 4274.416556920579),
#   ("MaximumProbability" (1; #20), 3468.9767767201656),
#   ("Imc2" (1; #14), 3064.037752251081),
#   ("Idm" (1; #10), 2829.2017802402793),
#   ("Id" (1; #9), 2293.2878191924815),
#   ("DifferenceVariance" (1; #8), 2006.9414261617435),
#   ("ClusterShade" (1; #2), 1961.4425295653239),
#   ("JointEnergy" (1; #17), 1851.5547348743323),
#   ("DifferenceEntropy" (1; #7), 1621.9453471763948),
#   ("Idmn" (1; #11), 1373.3661677897462),
#   ("Contrast" (1; #4), 1278.5641786046383),
#   ("SumEntropy" (1; #22), 1240.1384609995234),
#   ("Idn" (1; #12), 1239.3538486491411),
#   ("DifferenceAverage" (1; #6), 1169.493011579427),
#   ("JointEntropy" (1; #18), 1055.3428053259865),
#   ("SumSquares" (1; #23), 1013.3108847251123),
#   ("ClusterProminence" (1; #1), 978.8748232445924),
#   ("ClusterTendency" (1; #3), 903.689112151993)],
#  'NUM_NODES': [("SumAverage" (1; #21), 483.0),
#   ("Autocorrelation" (1; #0), 477.0),
#   ("JointAverage" (1; #16), 439.0),
#   ("Imc1" (1; #13), 271.0),
#   ("Correlation" (1; #5), 246.0),
#   ("InverseVariance" (1; #15), 240.0),
#   ("MaximumProbability" (1; #20), 232.0),
#   ("ClusterShade" (1; #2), 223.0),
#   ("MCC" (1; #19), 217.0),
#   ("Idm" (1; #10), 214.0),
#   ("Imc2" (1; #14), 207.0),
#   ("Id" (1; #9), 203.0),
#   ("JointEnergy" (1; #17), 179.0),
#   ("DifferenceVariance" (1; #8), 165.0),
#   ("SumEntropy" (1; #22), 145.0),
#   ("JointEntropy" (1; #18), 140.0),
#   ("DifferenceEntropy" (1; #7), 132.0),
#   ("Idmn" (1; #11), 130.0),
#   ("Idn" (1; #12), 122.0),
#   ("Contrast" (1; #4), 120.0),
#   ("DifferenceAverage" (1; #6), 117.0),
#   ("ClusterProminence" (1; #1), 110.0),
#   ("SumSquares" (1; #23), 110.0),
#   ("ClusterTendency" (1; #3), 103.0)]}

# %%
# Model self evaluation
model.make_inspector().evaluation()
# Out:
# Evaluation(num_examples=737, accuracy=0.9130915535235469, loss=0.23247741553099946, rmse=None, ndcg=None, aucs=None, auuc=None, qini=None)

# %%
logs = model.make_inspector().training_logs()

plt.figure(figsize=(12, 4))
plt.subplot(1, 2, 1)
plt.plot([log.num_trees for log in logs], [log.evaluation.accuracy for log in logs])
plt.xlabel("Number of trees")
plt.ylabel("Accuracy (out-of-bag)")
plt.subplot(1, 2, 2)
plt.plot([log.num_trees for log in logs], [log.evaluation.loss for log in logs])
plt.xlabel("Number of trees")
plt.ylabel("Logloss (out-of-bag)")
plt.show()

# %% [markdown]
# Calculate the score of our hold-out validation dataset

# %%
predictions = model.predict(val_ds)
y_true      = validation_data["label"]

from sklearn.metrics import roc_auc_score
ROC_AUC = roc_auc_score(y_true, predictions)
print("The ROC AUC score is %.5f" % ROC_AUC )
# Out:
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 66ms/step
# The ROC AUC score is 0.99372

# %%
# Compute binary classification metrics with sklearn
import numpy as np
from sklearn.metrics import (
    accuracy_score,
    precision_score,
    recall_score,
    f1_score,
    roc_auc_score,
    average_precision_score,
    confusion_matrix,
    classification_report,
    matthews_corrcoef,
    log_loss,
    brier_score_loss,
)

# Get predictions (probabilities or class labels)
preds = model.predict(test_ds)
# If model outputs probabilities, convert to labels by threshold 0.5
if preds.ndim == 2:
    # For TFDF classification, preds may be class probabilities with shape (N, 2)
    if preds.shape[1] == 2:
        pos_probs = preds[:, 1]
    else:
        # If single-probability column (positive class)
        pos_probs = preds[:, -1]
    y_pred = (pos_probs >= 0.5).astype(int)
else:
    # Already class labels
    y_pred = preds.astype(int)
    pos_probs = None

# Ground truth labels (must be 0/1 integers)
y_true = test_data["label"].astype(int).to_numpy()

# Core metrics
metrics = {}
metrics["accuracy"] = accuracy_score(y_true, y_pred)
metrics["precision"] = precision_score(y_true, y_pred, zero_division=0)
metrics["recall"] = recall_score(y_true, y_pred, zero_division=0)
metrics["f1"] = f1_score(y_true, y_pred, zero_division=0)
metrics["mcc"] = matthews_corrcoef(y_true, y_pred)

# Probabilistic metrics (only if we have probabilities)
if pos_probs is not None:
    metrics["roc_auc"] = roc_auc_score(y_true, pos_probs)
    metrics["pr_auc"] = average_precision_score(y_true, pos_probs)
    metrics["log_loss"] = log_loss(y_true, pos_probs, labels=[0,1])
    metrics["brier_score"] = brier_score_loss(y_true, pos_probs)

# Confusion matrix and detailed report
cm = confusion_matrix(y_true, y_pred, labels=[0,1])
report = classification_report(y_true, y_pred, digits=4)

print("Sklearn binary metrics:")
for k, v in metrics.items():
    print(f"{k}: {v:.4f}")
print("\nConfusion matrix:\n", cm)
print("\nClassification report:\n", report)
# Out:
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 79ms/step
# Sklearn binary metrics:
# accuracy: 0.9340
# precision: 0.7895
# recall: 0.8333
# f1: 0.8108
# mcc: 0.7713
# roc_auc: 0.9770
# pr_auc: 0.9009
# log_loss: 0.1481
# brier_score: 0.0461
#
# Confusion matrix:
#  [[168   8]
#  [  6  30]]
#
# Classification report:
#                precision    recall  f1-score   support
#
#            0     0.9655    0.9545    0.9600       176
#            1     0.7895    0.8333    0.8108        36
#
#     accuracy                         0.9340       212
#    macro avg     0.8775    0.8939    0.8854       212
# weighted avg     0.9356    0.9340    0.9347       212
