# %%
# Import packages and modules
import numpy  as np
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow_decision_forests as tfdf

from sklearn.model_selection import train_test_split
# Out:
# 2026-08-12 05:54:16.297524: I tensorflow/core/util/port.cc:113] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2026-08-12 05:54:16.743770: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2026-08-12 05:54:22.256186: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
# Check the version of TensorFlow Decision Forests
print("Found TensorFlow Decision Forests v" + tfdf.__version__)
# Out:
# Found TensorFlow Decision Forests v1.9.1

# %%
datasetPath = 'dataset/firstorder/kernel5-radius5/dataset.csv'

# %%
# Parameters
datasetPath = "dataset/gldm/kernel4/1.dataset.csv"

# %%
# train/validation/test = 70/10/20
dataset = pd.read_csv(datasetPath)

train_data, temp_data = train_test_split(dataset, test_size=0.3, random_state=42)
validation_data, test_data = train_test_split(temp_data, test_size=2/3, random_state=42)

# %%
from sklearn.utils.class_weight import compute_class_weight

# tinh class weight tren tap train
classes = np.array([0, 1])
weights = compute_class_weight(class_weight="balanced", classes=classes, y=train_data["label"])
class_weight = {0: weights[0], 1: weights[1]}

# gan sample_weight cho tung dong
train_data["sample_weight"] = train_data["label"].map(class_weight)
validation_data["sample_weight"] = validation_data["label"].map(class_weight)
test_data["sample_weight"] = test_data["label"].map(class_weight)

# Convert the dataset into a TensorFlow dataset.
train_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    train_data, label="label", weight="sample_weight"
)         
val_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    validation_data, label="label", weight="sample_weight"
)
test_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    test_data, label="label", weight="sample_weight"
)
# Out:
# 2026-08-12 05:54:40.358229: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:984] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2026-08-12 05:54:40.359836: W tensorflow/core/common_runtime/gpu/gpu_device.cc:2251] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...

# %%
import keras

# %%
# %%time

# Train a Random Forest model.
model = tfdf.keras.RandomForestModel()

# Add evaluation metrics
model.compile(
    metrics=["accuracy"]
)
model.fit(x=train_ds)

# # Train a Gradient Boosted Trees model.
# model = tfdf.keras.GradientBoostedTreesModel(num_trees=1500)
# model.fit(train_ds)
# Out:
# Use /tmp/tmpwgqt3ywn as temporary training directory
# Reading training dataset...
# Training dataset read in 0:00:02.882196. Found 1336 examples.
# Training model...
# Model trained in 0:00:00.086494
# Compiling model...
# [INFO 26-08-12 05:54:43.4851 UTC kernel.cc:1233] Loading model from path /tmp/tmpwgqt3ywn/model/ with prefix 972155b74bad46ca
# [INFO 26-08-12 05:54:43.5031 UTC decision_forest.cc:734] Model loaded with 300 root(s), 15232 node(s), and 14 input feature(s).
# [INFO 26-08-12 05:54:43.5032 UTC abstract_model.cc:1362] Engine "RandomForestOptPred" built
# [INFO 26-08-12 05:54:43.5032 UTC kernel.cc:1061] Use fast generic engine
# Model compiled.
# CPU times: user 6.68 s, sys: 172 ms, total: 6.85 s
# Wall time: 6.47 s

# %%
# Evaluate the model
evaluate = model.evaluate(val_ds, return_dict=True)
print()

for name, value in evaluate.items():
    print(f"{name}: {value:.4f}")
# Out:
# WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 1/1 [==============================] - ETA: 0s - loss: 0.0000e+00 - accuracy: 0.9634
# 1/1 [==============================] - 3s 3s/step - loss: 0.0000e+00 - accuracy: 0.9634
# loss: 0.0000
# accuracy: 0.9634

# %%
# Model Summary
model.summary()
# Out:
# Model: "random_forest_model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
# =================================================================
# Total params: 1 (1.00 Byte)
# Trainable params: 0 (0.00 Byte)
# Non-trainable params: 1 (1.00 Byte)
# _________________________________________________________________
# Type: "RANDOM_FOREST"
# Task: CLASSIFICATION
# Label: "__LABEL"
#
# Input Features (14):
# 	DependenceEntropy
# 	DependenceNonUniformity
# 	DependenceNonUniformityNormalized
# 	DependenceVariance
# 	GrayLevelNonUniformity
# 	GrayLevelVariance
# 	HighGrayLevelEmphasis
# 	LargeDependenceEmphasis
# 	LargeDependenceHighGrayLevelEmphasis
# 	LargeDependenceLowGrayLevelEmphasis
# 	LowGrayLevelEmphasis
# 	SmallDependenceEmphasis
# 	SmallDependenceHighGrayLevelEmphasis
# 	SmallDependenceLowGrayLevelEmphasis
#
# Trained with weights
#
# Variable Importance: INV_MEAN_MIN_DEPTH:
#     1.                "HighGrayLevelEmphasis"  0.315076 ################
#     2. "LargeDependenceHighGrayLevelEmphasis"  0.276306 ###########
#     3.                 "LowGrayLevelEmphasis"  0.248644 #########
#     4.  "SmallDependenceLowGrayLevelEmphasis"  0.199988 ####
#     5. "SmallDependenceHighGrayLevelEmphasis"  0.182245 ##
#     6.                    "DependenceEntropy"  0.179046 #
#     7.  "LargeDependenceLowGrayLevelEmphasis"  0.177781 #
#     8.                   "DependenceVariance"  0.166866
#     9.                    "GrayLevelVariance"  0.165511
#    10.               "GrayLevelNonUniformity"  0.164712
#    11.              "LargeDependenceEmphasis"  0.164013
#    12.    "DependenceNonUniformityNormalized"  0.163728
#    13.              "SmallDependenceEmphasis"  0.161901
#    14.              "DependenceNonUniformity"  0.160784
#
# Variable Importance: NUM_AS_ROOT:
#     1.                "HighGrayLevelEmphasis" 97.000000 ################
#     2.                 "LowGrayLevelEmphasis" 65.000000 ##########
#     3. "LargeDependenceHighGrayLevelEmphasis" 55.000000 #########
#     4.  "SmallDependenceLowGrayLevelEmphasis" 48.000000 #######
#     5.  "LargeDependenceLowGrayLevelEmphasis" 14.000000 ##
#     6. "SmallDependenceHighGrayLevelEmphasis" 11.000000 #
#     7.                   "DependenceVariance"  8.000000 #
#     8.                    "DependenceEntropy"  1.000000
#     9.              "LargeDependenceEmphasis"  1.000000
#
# Variable Importance: NUM_NODES:
#     1. "LargeDependenceHighGrayLevelEmphasis" 1013.000000 ################
#     2.                "HighGrayLevelEmphasis" 970.000000 ###############
#     3.                 "LowGrayLevelEmphasis" 703.000000 ########
#     4.                    "DependenceEntropy" 678.000000 ########
#     5.  "SmallDependenceLowGrayLevelEmphasis" 578.000000 ######
#     6. "SmallDependenceHighGrayLevelEmphasis" 542.000000 #####
#     7.                    "GrayLevelVariance" 447.000000 ###
#     8.  "LargeDependenceLowGrayLevelEmphasis" 438.000000 ##
#     9.               "GrayLevelNonUniformity" 429.000000 ##
#    10.              "SmallDependenceEmphasis" 378.000000 #
#    11.              "LargeDependenceEmphasis" 339.000000
#    12.                   "DependenceVariance" 337.000000
#    13.    "DependenceNonUniformityNormalized" 308.000000
#    14.              "DependenceNonUniformity" 306.000000
#
# Variable Importance: SUM_SCORE:
#     1.                "HighGrayLevelEmphasis" 88078.778242 ################
#     2. "LargeDependenceHighGrayLevelEmphasis" 51197.126375 #########
#     3.                 "LowGrayLevelEmphasis" 48205.883479 ########
#     4.  "SmallDependenceLowGrayLevelEmphasis" 20430.411408 ###
#     5.                    "DependenceEntropy" 11126.548951 #
#     6.  "LargeDependenceLowGrayLevelEmphasis" 9624.445043 #
#     7. "SmallDependenceHighGrayLevelEmphasis" 9247.589190 #
#     8.                    "GrayLevelVariance" 4934.165674
#     9.               "GrayLevelNonUniformity" 4622.646036
#    10.                   "DependenceVariance" 4070.753288
#    11.              "LargeDependenceEmphasis" 3651.141145
#    12.              "SmallDependenceEmphasis" 3492.533311
#    13.    "DependenceNonUniformityNormalized" 3320.397583
#    14.              "DependenceNonUniformity" 3191.549396
#
#
#
# Winner takes all: true
# Out-of-bag evaluation: accuracy:0.945678 logloss:0.23212
# Number of trees: 300
# Total number of nodes: 15232
#
# Number of nodes by tree:
# Count: 300 Average: 50.7733 StdDev: 6.00683
# Min: 35 Max: 69 Ignored: 0
# ----------------------------------------------
# [ 35, 36)  2   0.67%   0.67%
# [ 36, 38)  2   0.67%   1.33%
# [ 38, 40)  3   1.00%   2.33% #
# [ 40, 42) 12   4.00%   6.33% ###
# [ 42, 43)  0   0.00%   6.33%
# [ 43, 45) 24   8.00%  14.33% #####
# [ 45, 47) 24   8.00%  22.33% #####
# [ 47, 49) 31  10.33%  32.67% #######
# [ 49, 50) 33  11.00%  43.67% #######
# [ 50, 52) 42  14.00%  57.67% #########
# [ 52, 54) 45  15.00%  72.67% ##########
# [ 54, 56) 27   9.00%  81.67% ######
# [ 56, 57)  0   0.00%  81.67%
# [ 57, 59) 23   7.67%  89.33% #####
# [ 59, 61) 14   4.67%  94.00% ###
# [ 61, 63)  6   2.00%  96.00% #
# [ 63, 64)  5   1.67%  97.67% #
# [ 64, 66)  4   1.33%  99.00% #
# [ 66, 68)  2   0.67%  99.67%
# [ 68, 69]  1   0.33% 100.00%
#
# Depth by leafs:
# Count: 7766 Average: 5.64409 StdDev: 1.77001
# Min: 1 Max: 13 Ignored: 0
# ----------------------------------------------
# [  1,  2)   10   0.13%   0.13%
# [  2,  3)  162   2.09%   2.21% #
# [  3,  4)  681   8.77%  10.98% ####
# [  4,  5) 1266  16.30%  27.29% ########
# [  5,  6) 1662  21.40%  48.69% ##########
# [  6,  7) 1647  21.21%  69.89% ##########
# [  7,  8) 1158  14.91%  84.81% #######
# [  8,  9)  702   9.04%  93.84% ####
# [  9, 10)  350   4.51%  98.35% ##
# [ 10, 11)   94   1.21%  99.56% #
# [ 11, 12)   23   0.30%  99.86%
# [ 12, 13)    9   0.12%  99.97%
# [ 13, 13]    2   0.03% 100.00%
#
# Number of training obs by leaf:
# Count: 7766 Average: 51.6096 StdDev: 132.536
# Min: 5 Max: 904 Ignored: 0
# ----------------------------------------------
# [   5,  50) 6263  80.65%  80.65% ##########
# [  50,  95)  659   8.49%  89.13% #
# [  95, 140)  275   3.54%  92.67%
# [ 140, 185)  127   1.64%  94.31%
# [ 185, 230)   59   0.76%  95.07%
# [ 230, 275)   25   0.32%  95.39%
# [ 275, 320)   30   0.39%  95.78%
# [ 320, 365)   17   0.22%  96.00%
# [ 365, 410)   18   0.23%  96.23%
# [ 410, 455)   24   0.31%  96.54%
# [ 455, 500)   20   0.26%  96.79%
# [ 500, 545)   20   0.26%  97.05%
# [ 545, 590)   17   0.22%  97.27%
# [ 590, 635)   30   0.39%  97.66%
# [ 635, 680)   33   0.42%  98.08%
# [ 680, 725)   42   0.54%  98.62%
# [ 725, 770)   37   0.48%  99.10%
# [ 770, 815)   32   0.41%  99.51%
# [ 815, 860)   28   0.36%  99.87%
# [ 860, 904]   10   0.13% 100.00%
#
# Attribute in nodes:
# 	1013 : LargeDependenceHighGrayLevelEmphasis [NUMERICAL]
# 	970 : HighGrayLevelEmphasis [NUMERICAL]
# 	703 : LowGrayLevelEmphasis [NUMERICAL]
# 	678 : DependenceEntropy [NUMERICAL]
# 	578 : SmallDependenceLowGrayLevelEmphasis [NUMERICAL]
# 	542 : SmallDependenceHighGrayLevelEmphasis [NUMERICAL]
# 	447 : GrayLevelVariance [NUMERICAL]
# 	438 : LargeDependenceLowGrayLevelEmphasis [NUMERICAL]
# 	429 : GrayLevelNonUniformity [NUMERICAL]
# 	378 : SmallDependenceEmphasis [NUMERICAL]
# 	339 : LargeDependenceEmphasis [NUMERICAL]
# 	337 : DependenceVariance [NUMERICAL]
# 	308 : DependenceNonUniformityNormalized [NUMERICAL]
# 	306 : DependenceNonUniformity [NUMERICAL]
#
# Attribute in nodes with depth <= 0:
# 	97 : HighGrayLevelEmphasis [NUMERICAL]
# 	65 : LowGrayLevelEmphasis [NUMERICAL]
# 	55 : LargeDependenceHighGrayLevelEmphasis [NUMERICAL]
# 	48 : SmallDependenceLowGrayLevelEmphasis [NUMERICAL]
# 	14 : LargeDependenceLowGrayLevelEmphasis [NUMERICAL]
# 	11 : SmallDependenceHighGrayLevelEmphasis [NUMERICAL]
# 	8 : DependenceVariance [NUMERICAL]
# 	1 : LargeDependenceEmphasis [NUMERICAL]
# 	1 : DependenceEntropy [NUMERICAL]
#
# Attribute in nodes with depth <= 1:
# 	252 : HighGrayLevelEmphasis [NUMERICAL]
# 	180 : LargeDependenceHighGrayLevelEmphasis [NUMERICAL]
# 	175 : LowGrayLevelEmphasis [NUMERICAL]
# 	87 : SmallDependenceLowGrayLevelEmphasis [NUMERICAL]
# 	58 : LargeDependenceLowGrayLevelEmphasis [NUMERICAL]
# 	47 : SmallDependenceHighGrayLevelEmphasis [NUMERICAL]
# 	20 : DependenceEntropy [NUMERICAL]
# 	13 : LargeDependenceEmphasis [NUMERICAL]
# 	13 : DependenceVariance [NUMERICAL]
# 	12 : GrayLevelNonUniformity [NUMERICAL]
# 	12 : DependenceNonUniformityNormalized [NUMERICAL]
# 	9 : SmallDependenceEmphasis [NUMERICAL]
# 	7 : GrayLevelVariance [NUMERICAL]
# 	5 : DependenceNonUniformity [NUMERICAL]
#
# Attribute in nodes with depth <= 2:
# 	434 : HighGrayLevelEmphasis [NUMERICAL]
# 	361 : LargeDependenceHighGrayLevelEmphasis [NUMERICAL]
# 	294 : LowGrayLevelEmphasis [NUMERICAL]
# 	179 : SmallDependenceLowGrayLevelEmphasis [NUMERICAL]
# 	118 : LargeDependenceLowGrayLevelEmphasis [NUMERICAL]
# 	112 : DependenceEntropy [NUMERICAL]
# 	102 : SmallDependenceHighGrayLevelEmphasis [NUMERICAL]
# 	53 : DependenceVariance [NUMERICAL]
# 	48 : GrayLevelNonUniformity [NUMERICAL]
# 	47 : LargeDependenceEmphasis [NUMERICAL]
# 	44 : DependenceNonUniformityNormalized [NUMERICAL]
# 	42 : SmallDependenceEmphasis [NUMERICAL]
# 	41 : GrayLevelVariance [NUMERICAL]
# 	33 : DependenceNonUniformity [NUMERICAL]
#
# Attribute in nodes with depth <= 3:
# 	604 : HighGrayLevelEmphasis [NUMERICAL]
# 	554 : LargeDependenceHighGrayLevelEmphasis [NUMERICAL]
# 	403 : LowGrayLevelEmphasis [NUMERICAL]
# 	284 : SmallDependenceLowGrayLevelEmphasis [NUMERICAL]
# 	236 : DependenceEntropy [NUMERICAL]
# 	205 : SmallDependenceHighGrayLevelEmphasis [NUMERICAL]
# 	182 : LargeDependenceLowGrayLevelEmphasis [NUMERICAL]
# 	137 : GrayLevelVariance [NUMERICAL]
# 	130 : GrayLevelNonUniformity [NUMERICAL]
# 	121 : DependenceVariance [NUMERICAL]
# 	113 : SmallDependenceEmphasis [NUMERICAL]
# 	110 : LargeDependenceEmphasis [NUMERICAL]
# 	98 : DependenceNonUniformityNormalized [NUMERICAL]
# 	86 : DependenceNonUniformity [NUMERICAL]
#
# Attribute in nodes with depth <= 5:
# 	855 : LargeDependenceHighGrayLevelEmphasis [NUMERICAL]
# 	855 : HighGrayLevelEmphasis [NUMERICAL]
# 	603 : LowGrayLevelEmphasis [NUMERICAL]
# 	529 : DependenceEntropy [NUMERICAL]
# 	475 : SmallDependenceLowGrayLevelEmphasis [NUMERICAL]
# 	409 : SmallDependenceHighGrayLevelEmphasis [NUMERICAL]
# 	334 : LargeDependenceLowGrayLevelEmphasis [NUMERICAL]
# 	319 : GrayLevelVariance [NUMERICAL]
# 	318 : GrayLevelNonUniformity [NUMERICAL]
# 	283 : SmallDependenceEmphasis [NUMERICAL]
# 	246 : LargeDependenceEmphasis [NUMERICAL]
# 	240 : DependenceVariance [NUMERICAL]
# 	238 : DependenceNonUniformity [NUMERICAL]
# 	229 : DependenceNonUniformityNormalized [NUMERICAL]
#
# Condition type in nodes:
# 	7466 : HigherCondition
# Condition type in nodes with depth <= 0:
# 	300 : HigherCondition
# Condition type in nodes with depth <= 1:
# 	890 : HigherCondition
# Condition type in nodes with depth <= 2:
# 	1908 : HigherCondition
# Condition type in nodes with depth <= 3:
# 	3263 : HigherCondition
# Condition type in nodes with depth <= 5:
# 	5933 : HigherCondition
# Node format: NOT_SET
#
# Training OOB:
# 	trees: 1, Out-of-bag evaluation: accuracy:0.916484 logloss:3.01023
# 	trees: 11, Out-of-bag evaluation: accuracy:0.91995 logloss:1.15349
# 	trees: 21, Out-of-bag evaluation: accuracy:0.921122 logloss:0.60234
# 	trees: 31, Out-of-bag evaluation: accuracy:0.926821 logloss:0.443983
# 	trees: 41, Out-of-bag evaluation: accuracy:0.936025 logloss:0.42567
# 	trees: 51, Out-of-bag evaluation: accuracy:0.938656 logloss:0.42782
# 	trees: 62, Out-of-bag evaluation: accuracy:0.935588 logloss:0.348742
# 	trees: 72, Out-of-bag evaluation: accuracy:0.937347 logloss:0.344941
# 	trees: 82, Out-of-bag evaluation: accuracy:0.93822 logloss:0.329431
# 	trees: 93, Out-of-bag evaluation: accuracy:0.932084 logloss:0.328589
# 	trees: 103, Out-of-bag evaluation: accuracy:0.93252 logloss:0.326959
# 	trees: 113, Out-of-bag evaluation: accuracy:0.932957 logloss:0.326015
# 	trees: 123, Out-of-bag evaluation: accuracy:0.936025 logloss:0.324771
# 	trees: 133, Out-of-bag evaluation: accuracy:0.936025 logloss:0.32448
# 	trees: 143, Out-of-bag evaluation: accuracy:0.938656 logloss:0.322898
# 	trees: 153, Out-of-bag evaluation: accuracy:0.940415 logloss:0.322001
# 	trees: 163, Out-of-bag evaluation: accuracy:0.943047 logloss:0.237363
# 	trees: 173, Out-of-bag evaluation: accuracy:0.943047 logloss:0.235857
# 	trees: 183, Out-of-bag evaluation: accuracy:0.939979 logloss:0.235838
# 	trees: 193, Out-of-bag evaluation: accuracy:0.939979 logloss:0.23647
# 	trees: 203, Out-of-bag evaluation: accuracy:0.942174 logloss:0.234129
# 	trees: 213, Out-of-bag evaluation: accuracy:0.94261 logloss:0.234615
# 	trees: 223, Out-of-bag evaluation: accuracy:0.942174 logloss:0.233234
# 	trees: 233, Out-of-bag evaluation: accuracy:0.944806 logloss:0.233169
# 	trees: 243, Out-of-bag evaluation: accuracy:0.944806 logloss:0.232591
# 	trees: 253, Out-of-bag evaluation: accuracy:0.944806 logloss:0.23246
# 	trees: 263, Out-of-bag evaluation: accuracy:0.945678 logloss:0.232419
# 	trees: 274, Out-of-bag evaluation: accuracy:0.945678 logloss:0.233014
# 	trees: 284, Out-of-bag evaluation: accuracy:0.945678 logloss:0.23233
# 	trees: 294, Out-of-bag evaluation: accuracy:0.94261 logloss:0.232382
# 	trees: 300, Out-of-bag evaluation: accuracy:0.945678 logloss:0.23212

# %%
# Model features
model.make_inspector().features()
# Out:
# ["DependenceEntropy" (1; #0),
#  "DependenceNonUniformity" (1; #1),
#  "DependenceNonUniformityNormalized" (1; #2),
#  "DependenceVariance" (1; #3),
#  "GrayLevelNonUniformity" (1; #4),
#  "GrayLevelVariance" (1; #5),
#  "HighGrayLevelEmphasis" (1; #6),
#  "LargeDependenceEmphasis" (1; #7),
#  "LargeDependenceHighGrayLevelEmphasis" (1; #8),
#  "LargeDependenceLowGrayLevelEmphasis" (1; #9),
#  "LowGrayLevelEmphasis" (1; #10),
#  "SmallDependenceEmphasis" (1; #11),
#  "SmallDependenceHighGrayLevelEmphasis" (1; #12),
#  "SmallDependenceLowGrayLevelEmphasis" (1; #13)]

# %%
# Feature importance
model.make_inspector().variable_importances()
# Out:
# {'INV_MEAN_MIN_DEPTH': [("HighGrayLevelEmphasis" (1; #6), 0.3150763786507191),
#   ("LargeDependenceHighGrayLevelEmphasis" (1; #8), 0.2763057494739242),
#   ("LowGrayLevelEmphasis" (1; #10), 0.2486435038260074),
#   ("SmallDependenceLowGrayLevelEmphasis" (1; #13), 0.19998814921842328),
#   ("SmallDependenceHighGrayLevelEmphasis" (1; #12), 0.182244575686281),
#   ("DependenceEntropy" (1; #0), 0.17904629465508898),
#   ("LargeDependenceLowGrayLevelEmphasis" (1; #9), 0.17778091795001552),
#   ("DependenceVariance" (1; #3), 0.16686591830157657),
#   ("GrayLevelVariance" (1; #5), 0.16551085048222783),
#   ("GrayLevelNonUniformity" (1; #4), 0.1647117283995902),
#   ("LargeDependenceEmphasis" (1; #7), 0.16401311825148904),
#   ("DependenceNonUniformityNormalized" (1; #2), 0.1637283263092741),
#   ("SmallDependenceEmphasis" (1; #11), 0.16190081432547285),
#   ("DependenceNonUniformity" (1; #1), 0.16078411500050943)],
#  'SUM_SCORE': [("HighGrayLevelEmphasis" (1; #6), 88078.77824174083),
#   ("LargeDependenceHighGrayLevelEmphasis" (1; #8), 51197.12637525124),
#   ("LowGrayLevelEmphasis" (1; #10), 48205.8834792184),
#   ("SmallDependenceLowGrayLevelEmphasis" (1; #13), 20430.411408388187),
#   ("DependenceEntropy" (1; #0), 11126.548950523953),
#   ("LargeDependenceLowGrayLevelEmphasis" (1; #9), 9624.445042591711),
#   ("SmallDependenceHighGrayLevelEmphasis" (1; #12), 9247.58919037454),
#   ("GrayLevelVariance" (1; #5), 4934.165674140067),
#   ("GrayLevelNonUniformity" (1; #4), 4622.646036459403),
#   ("DependenceVariance" (1; #3), 4070.7532877535596),
#   ("LargeDependenceEmphasis" (1; #7), 3651.1411454290983),
#   ("SmallDependenceEmphasis" (1; #11), 3492.5333110681),
#   ("DependenceNonUniformityNormalized" (1; #2), 3320.3975831353105),
#   ("DependenceNonUniformity" (1; #1), 3191.549396064254)],
#  'NUM_AS_ROOT': [("HighGrayLevelEmphasis" (1; #6), 97.0),
#   ("LowGrayLevelEmphasis" (1; #10), 65.0),
#   ("LargeDependenceHighGrayLevelEmphasis" (1; #8), 55.0),
#   ("SmallDependenceLowGrayLevelEmphasis" (1; #13), 48.0),
#   ("LargeDependenceLowGrayLevelEmphasis" (1; #9), 14.0),
#   ("SmallDependenceHighGrayLevelEmphasis" (1; #12), 11.0),
#   ("DependenceVariance" (1; #3), 8.0),
#   ("DependenceEntropy" (1; #0), 1.0),
#   ("LargeDependenceEmphasis" (1; #7), 1.0)],
#  'NUM_NODES': [("LargeDependenceHighGrayLevelEmphasis" (1; #8), 1013.0),
#   ("HighGrayLevelEmphasis" (1; #6), 970.0),
#   ("LowGrayLevelEmphasis" (1; #10), 703.0),
#   ("DependenceEntropy" (1; #0), 678.0),
#   ("SmallDependenceLowGrayLevelEmphasis" (1; #13), 578.0),
#   ("SmallDependenceHighGrayLevelEmphasis" (1; #12), 542.0),
#   ("GrayLevelVariance" (1; #5), 447.0),
#   ("LargeDependenceLowGrayLevelEmphasis" (1; #9), 438.0),
#   ("GrayLevelNonUniformity" (1; #4), 429.0),
#   ("SmallDependenceEmphasis" (1; #11), 378.0),
#   ("LargeDependenceEmphasis" (1; #7), 339.0),
#   ("DependenceVariance" (1; #3), 337.0),
#   ("DependenceNonUniformityNormalized" (1; #2), 308.0),
#   ("DependenceNonUniformity" (1; #1), 306.0)]}

# %%
# Model self evaluation
model.make_inspector().evaluation()
# Out:
# Evaluation(num_examples=1336, accuracy=0.945678331147461, loss=0.2321195799848158, rmse=None, ndcg=None, aucs=None, auuc=None, qini=None)

# %%
logs = model.make_inspector().training_logs()

plt.figure(figsize=(12, 4))
plt.subplot(1, 2, 1)
plt.plot([log.num_trees for log in logs], [log.evaluation.accuracy for log in logs])
plt.xlabel("Number of trees")
plt.ylabel("Accuracy (out-of-bag)")
plt.subplot(1, 2, 2)
plt.plot([log.num_trees for log in logs], [log.evaluation.loss for log in logs])
plt.xlabel("Number of trees")
plt.ylabel("Logloss (out-of-bag)")
plt.show()

# %% [markdown]
# Calculate the score of our hold-out validation dataset

# %%
predictions = model.predict(val_ds)
y_true      = validation_data["label"]

from sklearn.metrics import roc_auc_score
ROC_AUC = roc_auc_score(y_true, predictions)
print("The ROC AUC score is %.5f" % ROC_AUC )
# Out:
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 65ms/step
# The ROC AUC score is 0.99068

# %%
# Compute binary classification metrics with sklearn
import numpy as np
from sklearn.metrics import (
    accuracy_score,
    precision_score,
    recall_score,
    f1_score,
    roc_auc_score,
    average_precision_score,
    confusion_matrix,
    classification_report,
    matthews_corrcoef,
    log_loss,
    brier_score_loss,
)

# Get predictions (probabilities or class labels)
preds = model.predict(test_ds)
# If model outputs probabilities, convert to labels by threshold 0.5
if preds.ndim == 2:
    # For TFDF classification, preds may be class probabilities with shape (N, 2)
    if preds.shape[1] == 2:
        pos_probs = preds[:, 1]
    else:
        # If single-probability column (positive class)
        pos_probs = preds[:, -1]
    y_pred = (pos_probs >= 0.5).astype(int)
else:
    # Already class labels
    y_pred = preds.astype(int)
    pos_probs = None

# Ground truth labels (must be 0/1 integers)
y_true = test_data["label"].astype(int).to_numpy()

# Core metrics
metrics = {}
metrics["accuracy"] = accuracy_score(y_true, y_pred)
metrics["precision"] = precision_score(y_true, y_pred, zero_division=0)
metrics["recall"] = recall_score(y_true, y_pred, zero_division=0)
metrics["f1"] = f1_score(y_true, y_pred, zero_division=0)
metrics["mcc"] = matthews_corrcoef(y_true, y_pred)

# Probabilistic metrics (only if we have probabilities)
if pos_probs is not None:
    metrics["roc_auc"] = roc_auc_score(y_true, pos_probs)
    metrics["pr_auc"] = average_precision_score(y_true, pos_probs)
    metrics["log_loss"] = log_loss(y_true, pos_probs, labels=[0,1])
    metrics["brier_score"] = brier_score_loss(y_true, pos_probs)

# Confusion matrix and detailed report
cm = confusion_matrix(y_true, y_pred, labels=[0,1])
report = classification_report(y_true, y_pred, digits=4)

print("Sklearn binary metrics:")
for k, v in metrics.items():
    print(f"{k}: {v:.4f}")
print("\nConfusion matrix:\n", cm)
print("\nClassification report:\n", report)
# Out:
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 72ms/step
# Sklearn binary metrics:
# accuracy: 0.9529
# precision: 0.7727
# recall: 0.8095
# f1: 0.7907
# mcc: 0.7644
# roc_auc: 0.9802
# pr_auc: 0.8929
# log_loss: 0.1138
# brier_score: 0.0341
#
# Confusion matrix:
#  [[330  10]
#  [  8  34]]
#
# Classification report:
#                precision    recall  f1-score   support
#
#            0     0.9763    0.9706    0.9735       340
#            1     0.7727    0.8095    0.7907        42
#
#     accuracy                         0.9529       382
#    macro avg     0.8745    0.8901    0.8821       382
# weighted avg     0.9539    0.9529    0.9534       382
