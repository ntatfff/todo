# %%
# Import packages and modules
import numpy  as np
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow_decision_forests as tfdf

from sklearn.model_selection import train_test_split
# Out:
# 2026-08-12 05:38:40.513242: I tensorflow/core/util/port.cc:113] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2026-08-12 05:38:44.061315: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2026-08-12 05:38:48.534606: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
# Check the version of TensorFlow Decision Forests
print("Found TensorFlow Decision Forests v" + tfdf.__version__)
# Out:
# Found TensorFlow Decision Forests v1.9.1

# %%
datasetPath = 'dataset/firstorder/kernel5-radius5/dataset.csv'

# %%
# Parameters
datasetPath = "dataset/ngtdm/kernel4/1.dataset.csv"

# %%
# train/validation/test = 70/10/20
dataset = pd.read_csv(datasetPath)

train_data, temp_data = train_test_split(dataset, test_size=0.3, random_state=42)
validation_data, test_data = train_test_split(temp_data, test_size=2/3, random_state=42)

# %%
from sklearn.utils.class_weight import compute_class_weight

# tinh class weight tren tap train
classes = np.array([0, 1])
weights = compute_class_weight(class_weight="balanced", classes=classes, y=train_data["label"])
class_weight = {0: weights[0], 1: weights[1]}

# gan sample_weight cho tung dong
train_data["sample_weight"] = train_data["label"].map(class_weight)
validation_data["sample_weight"] = validation_data["label"].map(class_weight)
test_data["sample_weight"] = test_data["label"].map(class_weight)

# Convert the dataset into a TensorFlow dataset.
train_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    train_data, label="label", weight="sample_weight"
)         
val_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    validation_data, label="label", weight="sample_weight"
)
test_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    test_data, label="label", weight="sample_weight"
)
# Out:
# 2026-08-12 05:39:00.704502: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:984] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2026-08-12 05:39:00.706014: W tensorflow/core/common_runtime/gpu/gpu_device.cc:2251] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...

# %%
import keras

# %%
# %%time

# Train a Gradient Boosted Trees model.
model = tfdf.keras.GradientBoostedTreesModel()

# Add evaluation metrics
model.compile(
    metrics=["accuracy"]
)
model.fit(x=train_ds)

# # Train a Gradient Boosted Trees model.
# model = tfdf.keras.GradientBoostedTreesModel(num_trees=1500)
# model.fit(train_ds)
# Out:
# Use /tmp/tmp6vm00d3q as temporary training directory
# Reading training dataset...
# [WARNING 26-08-12 05:39:00.8185 UTC gradient_boosted_trees.cc:1840] "goss_alpha" set but "sampling_method" not equal to "GOSS".
# [WARNING 26-08-12 05:39:00.8187 UTC gradient_boosted_trees.cc:1851] "goss_beta" set but "sampling_method" not equal to "GOSS".
# [WARNING 26-08-12 05:39:00.8187 UTC gradient_boosted_trees.cc:1865] "selective_gradient_boosting_ratio" set but "sampling_method" not equal to "SELGB".
# Training dataset read in 0:00:02.324651. Found 1336 examples.
# Training model...
# Model trained in 0:00:00.227738
# Compiling model...
# [INFO 26-08-12 05:39:03.4010 UTC kernel.cc:1233] Loading model from path /tmp/tmp6vm00d3q/model/ with prefix f273ccd6144f48ec
# [INFO 26-08-12 05:39:03.4040 UTC quick_scorer_extended.cc:911] The binary was compiled without AVX2 support, but your CPU supports it. Enable it for faster model inference.
# [INFO 26-08-12 05:39:03.4042 UTC abstract_model.cc:1362] Engine "GradientBoostedTreesQuickScorerExtended" built
# [INFO 26-08-12 05:39:03.4042 UTC kernel.cc:1061] Use fast generic engine
# Model compiled.
# CPU times: user 5.42 s, sys: 236 ms, total: 5.66 s
# Wall time: 5.43 s

# %%
# Evaluate the model
evaluate = model.evaluate(val_ds, return_dict=True)
print()

for name, value in evaluate.items():
    print(f"{name}: {value:.4f}")
# Out:
# WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 1/1 [==============================] - ETA: 0s - loss: 0.0000e+00 - accuracy: 0.9215
# 1/1 [==============================] - 3s 3s/step - loss: 0.0000e+00 - accuracy: 0.9215
# loss: 0.0000
# accuracy: 0.9215

# %%
# Model Summary
model.summary()
# Out:
# Model: "gradient_boosted_trees_model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
# =================================================================
# Total params: 1 (1.00 Byte)
# Trainable params: 0 (0.00 Byte)
# Non-trainable params: 1 (1.00 Byte)
# _________________________________________________________________
# Type: "GRADIENT_BOOSTED_TREES"
# Task: CLASSIFICATION
# Label: "__LABEL"
#
# Input Features (5):
# 	Busyness
# 	Coarseness
# 	Complexity
# 	Contrast
# 	Strength
#
# Trained with weights
#
# Variable Importance: INV_MEAN_MIN_DEPTH:
#     1.   "Busyness"  0.862403 ################
#     2. "Complexity"  0.314681 ##
#     3. "Coarseness"  0.229451
#     4.   "Strength"  0.212558
#     5.   "Contrast"  0.209566
#
# Variable Importance: NUM_AS_ROOT:
#     1.   "Busyness" 49.000000 ################
#     2. "Coarseness"  3.000000
#
# Variable Importance: NUM_NODES:
#     1.   "Busyness" 352.000000 ################
#     2. "Complexity" 255.000000 #######
#     3.   "Strength" 174.000000 #
#     4.   "Contrast" 169.000000
#     5. "Coarseness" 161.000000
#
# Variable Importance: SUM_SCORE:
#     1.   "Busyness" 1025.947442 ################
#     2. "Complexity" 320.146814 ####
#     3.   "Strength" 111.822183
#     4.   "Contrast" 62.943063
#     5. "Coarseness" 57.498770
#
#
#
# Loss: BINOMIAL_LOG_LIKELIHOOD
# Validation loss value: 0.597915
# Number of trees per iteration: 1
# Node format: NOT_SET
# Number of trees: 52
# Total number of nodes: 2274
#
# Number of nodes by tree:
# Count: 52 Average: 43.7308 StdDev: 9.33998
# Min: 19 Max: 59 Ignored: 0
# ----------------------------------------------
# [ 19, 21) 1   1.92%   1.92% #
# [ 21, 23) 0   0.00%   1.92%
# [ 23, 25) 1   1.92%   3.85% #
# [ 25, 27) 0   0.00%   3.85%
# [ 27, 29) 0   0.00%   3.85%
# [ 29, 31) 2   3.85%   7.69% ###
# [ 31, 33) 1   1.92%   9.62% #
# [ 33, 35) 4   7.69%  17.31% ######
# [ 35, 37) 3   5.77%  23.08% ####
# [ 37, 39) 5   9.62%  32.69% #######
# [ 39, 41) 0   0.00%  32.69%
# [ 41, 43) 4   7.69%  40.38% ######
# [ 43, 45) 4   7.69%  48.08% ######
# [ 45, 47) 4   7.69%  55.77% ######
# [ 47, 49) 2   3.85%  59.62% ###
# [ 49, 51) 3   5.77%  65.38% ####
# [ 51, 53) 7  13.46%  78.85% ##########
# [ 53, 55) 2   3.85%  82.69% ###
# [ 55, 57) 7  13.46%  96.15% ##########
# [ 57, 59] 2   3.85% 100.00% ###
#
# Depth by leafs:
# Count: 1163 Average: 4.69132 StdDev: 0.649216
# Min: 2 Max: 5 Ignored: 0
# ----------------------------------------------
# [ 2, 3)  21   1.81%   1.81%
# [ 3, 4)  58   4.99%   6.79% #
# [ 4, 5) 180  15.48%  22.27% ##
# [ 5, 5] 904  77.73% 100.00% ##########
#
# Number of training obs by leaf:
# Count: 1163 Average: 54.9063 StdDev: 139.811
# Min: 5 Max: 1029 Ignored: 0
# ----------------------------------------------
# [    5,   56) 972  83.58%  83.58% ##########
# [   56,  107)  76   6.53%  90.11% #
# [  107,  158)  36   3.10%  93.21%
# [  158,  210)  10   0.86%  94.07%
# [  210,  261)   6   0.52%  94.58%
# [  261,  312)   4   0.34%  94.93%
# [  312,  363)   1   0.09%  95.01%
# [  363,  415)   4   0.34%  95.36%
# [  415,  466)   2   0.17%  95.53%
# [  466,  517)  11   0.95%  96.47%
# [  517,  568)   5   0.43%  96.90%
# [  568,  620)   7   0.60%  97.51%
# [  620,  671)  13   1.12%  98.62%
# [  671,  722)   6   0.52%  99.14%
# [  722,  773)   1   0.09%  99.23%
# [  773,  825)   4   0.34%  99.57%
# [  825,  876)   1   0.09%  99.66%
# [  876,  927)   0   0.00%  99.66%
# [  927,  978)   1   0.09%  99.74%
# [  978, 1029]   3   0.26% 100.00%
#
# Attribute in nodes:
# 	352 : Busyness [NUMERICAL]
# 	255 : Complexity [NUMERICAL]
# 	174 : Strength [NUMERICAL]
# 	169 : Contrast [NUMERICAL]
# 	161 : Coarseness [NUMERICAL]
#
# Attribute in nodes with depth <= 0:
# 	49 : Busyness [NUMERICAL]
# 	3 : Coarseness [NUMERICAL]
#
# Attribute in nodes with depth <= 1:
# 	74 : Busyness [NUMERICAL]
# 	44 : Complexity [NUMERICAL]
# 	19 : Coarseness [NUMERICAL]
# 	12 : Strength [NUMERICAL]
# 	7 : Contrast [NUMERICAL]
#
# Attribute in nodes with depth <= 2:
# 	130 : Busyness [NUMERICAL]
# 	100 : Complexity [NUMERICAL]
# 	52 : Coarseness [NUMERICAL]
# 	35 : Contrast [NUMERICAL]
# 	26 : Strength [NUMERICAL]
#
# Attribute in nodes with depth <= 3:
# 	209 : Busyness [NUMERICAL]
# 	163 : Complexity [NUMERICAL]
# 	107 : Coarseness [NUMERICAL]
# 	92 : Strength [NUMERICAL]
# 	88 : Contrast [NUMERICAL]
#
# Attribute in nodes with depth <= 5:
# 	352 : Busyness [NUMERICAL]
# 	255 : Complexity [NUMERICAL]
# 	174 : Strength [NUMERICAL]
# 	169 : Contrast [NUMERICAL]
# 	161 : Coarseness [NUMERICAL]
#
# Condition type in nodes:
# 	1111 : HigherCondition
# Condition type in nodes with depth <= 0:
# 	52 : HigherCondition
# Condition type in nodes with depth <= 1:
# 	156 : HigherCondition
# Condition type in nodes with depth <= 2:
# 	343 : HigherCondition
# Condition type in nodes with depth <= 3:
# 	659 : HigherCondition
# Condition type in nodes with depth <= 5:
# 	1111 : HigherCondition
#
# Training logs:
# Number of iteration to final model: 52
# 	Iter:1 train-loss:1.230984 valid-loss:1.270788  train-accuracy:0.941748 valid-accuracy:0.844975
# 	Iter:2 train-loss:1.103204 valid-loss:1.167273  train-accuracy:0.945633 valid-accuracy:0.838780
# 	Iter:3 train-loss:0.998901 valid-loss:1.086183  train-accuracy:0.944850 valid-accuracy:0.844975
# 	Iter:4 train-loss:0.908223 valid-loss:1.020638  train-accuracy:0.952928 valid-accuracy:0.844975
# 	Iter:5 train-loss:0.830555 valid-loss:0.962851  train-accuracy:0.952928 valid-accuracy:0.844975
# 	Iter:6 train-loss:0.764428 valid-loss:0.923265  train-accuracy:0.952462 valid-accuracy:0.844975
# 	Iter:16 train-loss:0.388015 valid-loss:0.666120  train-accuracy:0.963494 valid-accuracy:0.857367
# 	Iter:26 train-loss:0.247415 valid-loss:0.600914  train-accuracy:0.976856 valid-accuracy:0.857367
# 	Iter:36 train-loss:0.182183 valid-loss:0.620739  train-accuracy:0.982605 valid-accuracy:0.863562
# 	Iter:46 train-loss:0.147296 valid-loss:0.610900  train-accuracy:0.988819 valid-accuracy:0.863562
# 	Iter:56 train-loss:0.121848 valid-loss:0.626551  train-accuracy:0.990683 valid-accuracy:0.863562
# 	Iter:66 train-loss:0.103766 valid-loss:0.648073  train-accuracy:0.992546 valid-accuracy:0.863562
# 	Iter:76 train-loss:0.088735 valid-loss:0.674561  train-accuracy:0.993944 valid-accuracy:0.863562

# %%
# Model features
model.make_inspector().features()
# Out:
# ["Busyness" (1; #0),
#  "Coarseness" (1; #1),
#  "Complexity" (1; #2),
#  "Contrast" (1; #3),
#  "Strength" (1; #4)]

# %%
# Feature importance
model.make_inspector().variable_importances()
# Out:
# {'INV_MEAN_MIN_DEPTH': [("Busyness" (1; #0), 0.8624027932074273),
#   ("Complexity" (1; #2), 0.31468065334889633),
#   ("Coarseness" (1; #1), 0.2294512837349888),
#   ("Strength" (1; #4), 0.2125580117807121),
#   ("Contrast" (1; #3), 0.2095657660742247)],
#  'SUM_SCORE': [("Busyness" (1; #0), 1025.9474420482418),
#   ("Complexity" (1; #2), 320.1468140990951),
#   ("Strength" (1; #4), 111.82218314860705),
#   ("Contrast" (1; #3), 62.94306252588645),
#   ("Coarseness" (1; #1), 57.49877040417729)],
#  'NUM_AS_ROOT': [("Busyness" (1; #0), 49.0), ("Coarseness" (1; #1), 3.0)],
#  'NUM_NODES': [("Busyness" (1; #0), 352.0),
#   ("Complexity" (1; #2), 255.0),
#   ("Strength" (1; #4), 174.0),
#   ("Contrast" (1; #3), 169.0),
#   ("Coarseness" (1; #1), 161.0)]}

# %%
# Model self evaluation
model.make_inspector().evaluation()
# Out:
# Evaluation(num_examples=None, accuracy=0.8635621070861816, loss=0.5979145169258118, rmse=None, ndcg=None, aucs=None, auuc=None, qini=None)

# %%
logs = model.make_inspector().training_logs()

plt.figure(figsize=(12, 4))
plt.subplot(1, 2, 1)
plt.plot([log.num_trees for log in logs], [log.evaluation.accuracy for log in logs])
plt.xlabel("Number of trees")
plt.ylabel("Accuracy (out-of-bag)")
plt.subplot(1, 2, 2)
plt.plot([log.num_trees for log in logs], [log.evaluation.loss for log in logs])
plt.xlabel("Number of trees")
plt.ylabel("Logloss (out-of-bag)")
plt.show()

# %% [markdown]
# Calculate the score of our hold-out validation dataset

# %%
predictions = model.predict(val_ds)
y_true      = validation_data["label"]

from sklearn.metrics import roc_auc_score
ROC_AUC = roc_auc_score(y_true, predictions)
print("The ROC AUC score is %.5f" % ROC_AUC )
# Out:
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 48ms/step
# The ROC AUC score is 0.97087

# %%
# Compute binary classification metrics with sklearn
import numpy as np
from sklearn.metrics import (
    accuracy_score,
    precision_score,
    recall_score,
    f1_score,
    roc_auc_score,
    average_precision_score,
    confusion_matrix,
    classification_report,
    matthews_corrcoef,
    log_loss,
    brier_score_loss,
)

# Get predictions (probabilities or class labels)
preds = model.predict(test_ds)
# If model outputs probabilities, convert to labels by threshold 0.5
if preds.ndim == 2:
    # For TFDF classification, preds may be class probabilities with shape (N, 2)
    if preds.shape[1] == 2:
        pos_probs = preds[:, 1]
    else:
        # If single-probability column (positive class)
        pos_probs = preds[:, -1]
    y_pred = (pos_probs >= 0.5).astype(int)
else:
    # Already class labels
    y_pred = preds.astype(int)
    pos_probs = None

# Ground truth labels (must be 0/1 integers)
y_true = test_data["label"].astype(int).to_numpy()

# Core metrics
metrics = {}
metrics["accuracy"] = accuracy_score(y_true, y_pred)
metrics["precision"] = precision_score(y_true, y_pred, zero_division=0)
metrics["recall"] = recall_score(y_true, y_pred, zero_division=0)
metrics["f1"] = f1_score(y_true, y_pred, zero_division=0)
metrics["mcc"] = matthews_corrcoef(y_true, y_pred)

# Probabilistic metrics (only if we have probabilities)
if pos_probs is not None:
    metrics["roc_auc"] = roc_auc_score(y_true, pos_probs)
    metrics["pr_auc"] = average_precision_score(y_true, pos_probs)
    metrics["log_loss"] = log_loss(y_true, pos_probs, labels=[0,1])
    metrics["brier_score"] = brier_score_loss(y_true, pos_probs)

# Confusion matrix and detailed report
cm = confusion_matrix(y_true, y_pred, labels=[0,1])
report = classification_report(y_true, y_pred, digits=4)

print("Sklearn binary metrics:")
for k, v in metrics.items():
    print(f"{k}: {v:.4f}")
print("\nConfusion matrix:\n", cm)
print("\nClassification report:\n", report)
# Out:
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 56ms/step
# Sklearn binary metrics:
# accuracy: 0.9346
# precision: 0.7258
# recall: 0.8491
# f1: 0.7826
# mcc: 0.7475
# roc_auc: 0.9698
# pr_auc: 0.8197
# log_loss: 0.1736
# brier_score: 0.0491
#
# Confusion matrix:
#  [[312  17]
#  [  8  45]]
#
# Classification report:
#                precision    recall  f1-score   support
#
#            0     0.9750    0.9483    0.9615       329
#            1     0.7258    0.8491    0.7826        53
#
#     accuracy                         0.9346       382
#    macro avg     0.8504    0.8987    0.8720       382
# weighted avg     0.9404    0.9346    0.9367       382
