# %%
# Import packages and modules
import numpy  as np
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow_decision_forests as tfdf

from sklearn.model_selection import train_test_split
# Out:
# 2026-08-12 05:55:34.908035: I tensorflow/core/util/port.cc:113] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2026-08-12 05:55:35.293537: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2026-08-12 05:55:42.611617: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
# Check the version of TensorFlow Decision Forests
print("Found TensorFlow Decision Forests v" + tfdf.__version__)
# Out:
# Found TensorFlow Decision Forests v1.9.1

# %%
datasetPath = 'dataset/firstorder/kernel5-radius5/dataset.csv'

# %%
# Parameters
datasetPath = "dataset/glszm/kernel4/1.dataset.csv"

# %%
# train/validation/test = 70/10/20
dataset = pd.read_csv(datasetPath)

train_data, temp_data = train_test_split(dataset, test_size=0.3, random_state=42)
validation_data, test_data = train_test_split(temp_data, test_size=2/3, random_state=42)

# %%
from sklearn.utils.class_weight import compute_class_weight

# tinh class weight tren tap train
classes = np.array([0, 1])
weights = compute_class_weight(class_weight="balanced", classes=classes, y=train_data["label"])
class_weight = {0: weights[0], 1: weights[1]}

# gan sample_weight cho tung dong
train_data["sample_weight"] = train_data["label"].map(class_weight)
validation_data["sample_weight"] = validation_data["label"].map(class_weight)
test_data["sample_weight"] = test_data["label"].map(class_weight)

# Convert the dataset into a TensorFlow dataset.
train_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    train_data, label="label", weight="sample_weight"
)         
val_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    validation_data, label="label", weight="sample_weight"
)
test_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    test_data, label="label", weight="sample_weight"
)
# Out:
# 2026-08-12 05:55:55.011928: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:984] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2026-08-12 05:55:55.013214: W tensorflow/core/common_runtime/gpu/gpu_device.cc:2251] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...

# %%
import keras

# %%
# %%time

# Train a Random Forest model.
model = tfdf.keras.RandomForestModel()

# Add evaluation metrics
model.compile(
    metrics=["accuracy"]
)
model.fit(x=train_ds)

# # Train a Gradient Boosted Trees model.
# model = tfdf.keras.GradientBoostedTreesModel(num_trees=1500)
# model.fit(train_ds)
# Out:
# Use /tmp/tmppmd5fskf as temporary training directory
# Reading training dataset...
# Training dataset read in 0:00:02.470734. Found 1336 examples.
# Training model...
# Model trained in 0:00:00.099624
# Compiling model...
# [INFO 26-08-12 05:55:57.7386 UTC kernel.cc:1233] Loading model from path /tmp/tmppmd5fskf/model/ with prefix aabb4439a53c44e4
# [INFO 26-08-12 05:55:57.7625 UTC decision_forest.cc:734] Model loaded with 300 root(s), 19838 node(s), and 16 input feature(s).
# [INFO 26-08-12 05:55:57.7625 UTC abstract_model.cc:1362] Engine "RandomForestOptPred" built
# [INFO 26-08-12 05:55:57.7625 UTC kernel.cc:1061] Use fast generic engine
# Model compiled.
# CPU times: user 5.89 s, sys: 117 ms, total: 6.01 s
# Wall time: 5.61 s

# %%
# Evaluate the model
evaluate = model.evaluate(val_ds, return_dict=True)
print()

for name, value in evaluate.items():
    print(f"{name}: {value:.4f}")
# Out:
# WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 1/1 [==============================] - ETA: 0s - loss: 0.0000e+00 - accuracy: 0.9267
# 1/1 [==============================] - 3s 3s/step - loss: 0.0000e+00 - accuracy: 0.9267
# loss: 0.0000
# accuracy: 0.9267

# %%
# Model Summary
model.summary()
# Out:
# Model: "random_forest_model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
# =================================================================
# Total params: 1 (1.00 Byte)
# Trainable params: 0 (0.00 Byte)
# Non-trainable params: 1 (1.00 Byte)
# _________________________________________________________________
# Type: "RANDOM_FOREST"
# Task: CLASSIFICATION
# Label: "__LABEL"
#
# Input Features (16):
# 	GrayLevelNonUniformity
# 	GrayLevelNonUniformityNormalized
# 	GrayLevelVariance
# 	HighGrayLevelZoneEmphasis
# 	LargeAreaEmphasis
# 	LargeAreaHighGrayLevelEmphasis
# 	LargeAreaLowGrayLevelEmphasis
# 	LowGrayLevelZoneEmphasis
# 	SizeZoneNonUniformity
# 	SizeZoneNonUniformityNormalized
# 	SmallAreaEmphasis
# 	SmallAreaHighGrayLevelEmphasis
# 	SmallAreaLowGrayLevelEmphasis
# 	ZoneEntropy
# 	ZonePercentage
# 	ZoneVariance
#
# Trained with weights
#
# Variable Importance: INV_MEAN_MIN_DEPTH:
#     1.        "HighGrayLevelZoneEmphasis"  0.295365 ################
#     2.    "SmallAreaLowGrayLevelEmphasis"  0.207742 ######
#     3.           "GrayLevelNonUniformity"  0.203633 ######
#     4.   "LargeAreaHighGrayLevelEmphasis"  0.202566 ######
#     5.         "LowGrayLevelZoneEmphasis"  0.201561 ######
#     6.   "SmallAreaHighGrayLevelEmphasis"  0.187926 ####
#     7.    "LargeAreaLowGrayLevelEmphasis"  0.161977 #
#     8.                "GrayLevelVariance"  0.158510 #
#     9. "GrayLevelNonUniformityNormalized"  0.155904 #
#    10.                      "ZoneEntropy"  0.150564
#    11.                     "ZoneVariance"  0.149298
#    12.                "LargeAreaEmphasis"  0.148006
#    13.                "SmallAreaEmphasis"  0.147793
#    14.                   "ZonePercentage"  0.147529
#    15.  "SizeZoneNonUniformityNormalized"  0.145005
#    16.            "SizeZoneNonUniformity"  0.144638
#
# Variable Importance: NUM_AS_ROOT:
#     1.       "HighGrayLevelZoneEmphasis" 94.000000 ################
#     2.   "SmallAreaLowGrayLevelEmphasis" 68.000000 ###########
#     3.        "LowGrayLevelZoneEmphasis" 60.000000 ##########
#     4.  "SmallAreaHighGrayLevelEmphasis" 33.000000 #####
#     5.  "LargeAreaHighGrayLevelEmphasis" 23.000000 ###
#     6.          "GrayLevelNonUniformity"  9.000000 #
#     7.   "LargeAreaLowGrayLevelEmphasis"  4.000000
#     8.               "SmallAreaEmphasis"  4.000000
#     9. "SizeZoneNonUniformityNormalized"  3.000000
#    10.                     "ZoneEntropy"  2.000000
#
# Variable Importance: NUM_NODES:
#     1.   "LargeAreaHighGrayLevelEmphasis" 980.000000 ################
#     2.           "GrayLevelNonUniformity" 960.000000 ###############
#     3.        "HighGrayLevelZoneEmphasis" 954.000000 ###############
#     4.    "SmallAreaLowGrayLevelEmphasis" 732.000000 #########
#     5.         "LowGrayLevelZoneEmphasis" 684.000000 ########
#     6.   "SmallAreaHighGrayLevelEmphasis" 671.000000 #######
#     7.    "LargeAreaLowGrayLevelEmphasis" 636.000000 ######
#     8. "GrayLevelNonUniformityNormalized" 618.000000 ######
#     9.                "GrayLevelVariance" 593.000000 #####
#    10.                      "ZoneEntropy" 508.000000 ###
#    11.                     "ZoneVariance" 462.000000 ##
#    12.                "SmallAreaEmphasis" 416.000000 #
#    13.                "LargeAreaEmphasis" 413.000000 #
#    14.  "SizeZoneNonUniformityNormalized" 395.000000
#    15.            "SizeZoneNonUniformity" 378.000000
#    16.                   "ZonePercentage" 369.000000
#
# Variable Importance: SUM_SCORE:
#     1.        "HighGrayLevelZoneEmphasis" 66925.901080 ################
#     2.    "SmallAreaLowGrayLevelEmphasis" 36709.332824 ########
#     3.         "LowGrayLevelZoneEmphasis" 33163.803438 #######
#     4.           "GrayLevelNonUniformity" 25273.460312 #####
#     5.   "SmallAreaHighGrayLevelEmphasis" 23700.284007 #####
#     6.   "LargeAreaHighGrayLevelEmphasis" 22423.787114 ####
#     7.    "LargeAreaLowGrayLevelEmphasis" 8703.970228 #
#     8. "GrayLevelNonUniformityNormalized" 8286.129540 #
#     9.                "GrayLevelVariance" 7683.805258 #
#    10.                      "ZoneEntropy" 5663.798058
#    11.                     "ZoneVariance" 4642.910955
#    12.                "LargeAreaEmphasis" 4134.077798
#    13.                "SmallAreaEmphasis" 3772.239362
#    14.                   "ZonePercentage" 3752.226096
#    15.  "SizeZoneNonUniformityNormalized" 3444.253010
#    16.            "SizeZoneNonUniformity" 3139.828727
#
#
#
# Winner takes all: true
# Out-of-bag evaluation: accuracy:0.909862 logloss:0.309668
# Number of trees: 300
# Total number of nodes: 19838
#
# Number of nodes by tree:
# Count: 300 Average: 66.1267 StdDev: 5.42316
# Min: 51 Max: 83 Ignored: 0
# ----------------------------------------------
# [ 51, 52)  1   0.33%   0.33%
# [ 52, 54)  3   1.00%   1.33% #
# [ 54, 55)  0   0.00%   1.33%
# [ 55, 57)  9   3.00%   4.33% ##
# [ 57, 59)  6   2.00%   6.33% #
# [ 59, 60) 22   7.33%  13.67% ####
# [ 60, 62) 23   7.67%  21.33% #####
# [ 62, 64) 34  11.33%  32.67% #######
# [ 64, 65)  0   0.00%  32.67%
# [ 65, 67) 47  15.67%  48.33% ##########
# [ 67, 69) 49  16.33%  64.67% ##########
# [ 69, 70) 37  12.33%  77.00% ########
# [ 70, 72) 26   8.67%  85.67% #####
# [ 72, 74) 25   8.33%  94.00% #####
# [ 74, 75)  0   0.00%  94.00%
# [ 75, 77)  7   2.33%  96.33% #
# [ 77, 79)  6   2.00%  98.33% #
# [ 79, 80)  4   1.33%  99.67% #
# [ 80, 82)  0   0.00%  99.67%
# [ 82, 83]  1   0.33% 100.00%
#
# Depth by leafs:
# Count: 10069 Average: 6.31215 StdDev: 2.06965
# Min: 1 Max: 15 Ignored: 0
# ----------------------------------------------
# [  1,  2)    1   0.01%   0.01%
# [  2,  3)  176   1.75%   1.76% #
# [  3,  4)  619   6.15%   7.91% ###
# [  4,  5) 1193  11.85%  19.75% ######
# [  5,  6) 1706  16.94%  36.70% #########
# [  6,  7) 1905  18.92%  55.62% ##########
# [  7,  8) 1709  16.97%  72.59% #########
# [  8,  9) 1319  13.10%  85.69% #######
# [  9, 10)  775   7.70%  93.39% ####
# [ 10, 11)  356   3.54%  96.92% ##
# [ 11, 12)  194   1.93%  98.85% #
# [ 12, 13)   89   0.88%  99.73%
# [ 13, 14)   19   0.19%  99.92%
# [ 14, 15)    4   0.04%  99.96%
# [ 15, 15]    4   0.04% 100.00%
#
# Number of training obs by leaf:
# Count: 10069 Average: 39.8053 StdDev: 92.8322
# Min: 5 Max: 746 Ignored: 0
# ----------------------------------------------
# [   5,  42) 8247  81.90%  81.90% ##########
# [  42,  79)  694   6.89%  88.80% #
# [  79, 116)  329   3.27%  92.06%
# [ 116, 153)  151   1.50%  93.56%
# [ 153, 190)  108   1.07%  94.64%
# [ 190, 227)   77   0.76%  95.40%
# [ 227, 264)   65   0.65%  96.05%
# [ 264, 301)   59   0.59%  96.63%
# [ 301, 338)   44   0.44%  97.07%
# [ 338, 376)   42   0.42%  97.49%
# [ 376, 413)   27   0.27%  97.76%
# [ 413, 450)   32   0.32%  98.07%
# [ 450, 487)   46   0.46%  98.53%
# [ 487, 524)   48   0.48%  99.01%
# [ 524, 561)   37   0.37%  99.37%
# [ 561, 598)   19   0.19%  99.56%
# [ 598, 635)   18   0.18%  99.74%
# [ 635, 672)   11   0.11%  99.85%
# [ 672, 709)    8   0.08%  99.93%
# [ 709, 746]    7   0.07% 100.00%
#
# Attribute in nodes:
# 	980 : LargeAreaHighGrayLevelEmphasis [NUMERICAL]
# 	960 : GrayLevelNonUniformity [NUMERICAL]
# 	954 : HighGrayLevelZoneEmphasis [NUMERICAL]
# 	732 : SmallAreaLowGrayLevelEmphasis [NUMERICAL]
# 	684 : LowGrayLevelZoneEmphasis [NUMERICAL]
# 	671 : SmallAreaHighGrayLevelEmphasis [NUMERICAL]
# 	636 : LargeAreaLowGrayLevelEmphasis [NUMERICAL]
# 	618 : GrayLevelNonUniformityNormalized [NUMERICAL]
# 	593 : GrayLevelVariance [NUMERICAL]
# 	508 : ZoneEntropy [NUMERICAL]
# 	462 : ZoneVariance [NUMERICAL]
# 	416 : SmallAreaEmphasis [NUMERICAL]
# 	413 : LargeAreaEmphasis [NUMERICAL]
# 	395 : SizeZoneNonUniformityNormalized [NUMERICAL]
# 	378 : SizeZoneNonUniformity [NUMERICAL]
# 	369 : ZonePercentage [NUMERICAL]
#
# Attribute in nodes with depth <= 0:
# 	94 : HighGrayLevelZoneEmphasis [NUMERICAL]
# 	68 : SmallAreaLowGrayLevelEmphasis [NUMERICAL]
# 	60 : LowGrayLevelZoneEmphasis [NUMERICAL]
# 	33 : SmallAreaHighGrayLevelEmphasis [NUMERICAL]
# 	23 : LargeAreaHighGrayLevelEmphasis [NUMERICAL]
# 	9 : GrayLevelNonUniformity [NUMERICAL]
# 	4 : SmallAreaEmphasis [NUMERICAL]
# 	4 : LargeAreaLowGrayLevelEmphasis [NUMERICAL]
# 	3 : SizeZoneNonUniformityNormalized [NUMERICAL]
# 	2 : ZoneEntropy [NUMERICAL]
#
# Attribute in nodes with depth <= 1:
# 	235 : HighGrayLevelZoneEmphasis [NUMERICAL]
# 	149 : SmallAreaLowGrayLevelEmphasis [NUMERICAL]
# 	140 : LowGrayLevelZoneEmphasis [NUMERICAL]
# 	107 : SmallAreaHighGrayLevelEmphasis [NUMERICAL]
# 	93 : LargeAreaHighGrayLevelEmphasis [NUMERICAL]
# 	78 : GrayLevelNonUniformity [NUMERICAL]
# 	26 : LargeAreaLowGrayLevelEmphasis [NUMERICAL]
# 	21 : GrayLevelVariance [NUMERICAL]
# 	10 : SizeZoneNonUniformityNormalized [NUMERICAL]
# 	9 : ZoneVariance [NUMERICAL]
# 	9 : ZoneEntropy [NUMERICAL]
# 	6 : SmallAreaEmphasis [NUMERICAL]
# 	5 : SizeZoneNonUniformity [NUMERICAL]
# 	4 : LargeAreaEmphasis [NUMERICAL]
# 	4 : GrayLevelNonUniformityNormalized [NUMERICAL]
# 	3 : ZonePercentage [NUMERICAL]
#
# Attribute in nodes with depth <= 2:
# 	364 : HighGrayLevelZoneEmphasis [NUMERICAL]
# 	263 : SmallAreaLowGrayLevelEmphasis [NUMERICAL]
# 	220 : LowGrayLevelZoneEmphasis [NUMERICAL]
# 	201 : LargeAreaHighGrayLevelEmphasis [NUMERICAL]
# 	199 : GrayLevelNonUniformity [NUMERICAL]
# 	187 : SmallAreaHighGrayLevelEmphasis [NUMERICAL]
# 	89 : LargeAreaLowGrayLevelEmphasis [NUMERICAL]
# 	80 : GrayLevelVariance [NUMERICAL]
# 	57 : GrayLevelNonUniformityNormalized [NUMERICAL]
# 	50 : ZoneVariance [NUMERICAL]
# 	40 : ZoneEntropy [NUMERICAL]
# 	39 : LargeAreaEmphasis [NUMERICAL]
# 	38 : ZonePercentage [NUMERICAL]
# 	37 : SmallAreaEmphasis [NUMERICAL]
# 	32 : SizeZoneNonUniformityNormalized [NUMERICAL]
# 	25 : SizeZoneNonUniformity [NUMERICAL]
#
# Attribute in nodes with depth <= 3:
# 	480 : HighGrayLevelZoneEmphasis [NUMERICAL]
# 	373 : LargeAreaHighGrayLevelEmphasis [NUMERICAL]
# 	360 : SmallAreaLowGrayLevelEmphasis [NUMERICAL]
# 	359 : GrayLevelNonUniformity [NUMERICAL]
# 	292 : LowGrayLevelZoneEmphasis [NUMERICAL]
# 	272 : SmallAreaHighGrayLevelEmphasis [NUMERICAL]
# 	192 : LargeAreaLowGrayLevelEmphasis [NUMERICAL]
# 	173 : GrayLevelVariance [NUMERICAL]
# 	172 : GrayLevelNonUniformityNormalized [NUMERICAL]
# 	127 : ZoneEntropy [NUMERICAL]
# 	108 : ZoneVariance [NUMERICAL]
# 	96 : SmallAreaEmphasis [NUMERICAL]
# 	96 : LargeAreaEmphasis [NUMERICAL]
# 	86 : ZonePercentage [NUMERICAL]
# 	80 : SizeZoneNonUniformityNormalized [NUMERICAL]
# 	80 : SizeZoneNonUniformity [NUMERICAL]
#
# Attribute in nodes with depth <= 5:
# 	726 : HighGrayLevelZoneEmphasis [NUMERICAL]
# 	693 : GrayLevelNonUniformity [NUMERICAL]
# 	683 : LargeAreaHighGrayLevelEmphasis [NUMERICAL]
# 	545 : SmallAreaLowGrayLevelEmphasis [NUMERICAL]
# 	480 : LowGrayLevelZoneEmphasis [NUMERICAL]
# 	478 : SmallAreaHighGrayLevelEmphasis [NUMERICAL]
# 	420 : LargeAreaLowGrayLevelEmphasis [NUMERICAL]
# 	404 : GrayLevelVariance [NUMERICAL]
# 	394 : GrayLevelNonUniformityNormalized [NUMERICAL]
# 	322 : ZoneEntropy [NUMERICAL]
# 	285 : ZoneVariance [NUMERICAL]
# 	263 : SmallAreaEmphasis [NUMERICAL]
# 	243 : LargeAreaEmphasis [NUMERICAL]
# 	229 : ZonePercentage [NUMERICAL]
# 	225 : SizeZoneNonUniformity [NUMERICAL]
# 	221 : SizeZoneNonUniformityNormalized [NUMERICAL]
#
# Condition type in nodes:
# 	9769 : HigherCondition
# Condition type in nodes with depth <= 0:
# 	300 : HigherCondition
# Condition type in nodes with depth <= 1:
# 	899 : HigherCondition
# Condition type in nodes with depth <= 2:
# 	1921 : HigherCondition
# Condition type in nodes with depth <= 3:
# 	3346 : HigherCondition
# Condition type in nodes with depth <= 5:
# 	6611 : HigherCondition
# Node format: NOT_SET
#
# Training OOB:
# 	trees: 1, Out-of-bag evaluation: accuracy:0.84187 logloss:5.69957
# 	trees: 11, Out-of-bag evaluation: accuracy:0.882244 logloss:1.19322
# 	trees: 21, Out-of-bag evaluation: accuracy:0.907699 logloss:0.780968
# 	trees: 33, Out-of-bag evaluation: accuracy:0.915667 logloss:0.744344
# 	trees: 43, Out-of-bag evaluation: accuracy:0.913072 logloss:0.51858
# 	trees: 53, Out-of-bag evaluation: accuracy:0.917762 logloss:0.413432
# 	trees: 63, Out-of-bag evaluation: accuracy:0.912639 logloss:0.420472
# 	trees: 74, Out-of-bag evaluation: accuracy:0.92054 logloss:0.415487
# 	trees: 84, Out-of-bag evaluation: accuracy:0.921405 logloss:0.317935
# 	trees: 95, Out-of-bag evaluation: accuracy:0.914985 logloss:0.317718
# 	trees: 106, Out-of-bag evaluation: accuracy:0.914552 logloss:0.319246
# 	trees: 117, Out-of-bag evaluation: accuracy:0.913072 logloss:0.321731
# 	trees: 127, Out-of-bag evaluation: accuracy:0.910294 logloss:0.322176
# 	trees: 137, Out-of-bag evaluation: accuracy:0.909862 logloss:0.318992
# 	trees: 147, Out-of-bag evaluation: accuracy:0.915417 logloss:0.319757
# 	trees: 157, Out-of-bag evaluation: accuracy:0.912639 logloss:0.321953
# 	trees: 167, Out-of-bag evaluation: accuracy:0.913072 logloss:0.322011
# 	trees: 177, Out-of-bag evaluation: accuracy:0.913072 logloss:0.320807
# 	trees: 188, Out-of-bag evaluation: accuracy:0.909862 logloss:0.321291
# 	trees: 198, Out-of-bag evaluation: accuracy:0.913072 logloss:0.322396
# 	trees: 209, Out-of-bag evaluation: accuracy:0.912639 logloss:0.323151
# 	trees: 219, Out-of-bag evaluation: accuracy:0.914985 logloss:0.323356
# 	trees: 229, Out-of-bag evaluation: accuracy:0.914985 logloss:0.323757
# 	trees: 239, Out-of-bag evaluation: accuracy:0.908997 logloss:0.324424
# 	trees: 249, Out-of-bag evaluation: accuracy:0.909429 logloss:0.32271
# 	trees: 259, Out-of-bag evaluation: accuracy:0.909429 logloss:0.323059
# 	trees: 269, Out-of-bag evaluation: accuracy:0.909429 logloss:0.323927
# 	trees: 279, Out-of-bag evaluation: accuracy:0.912207 logloss:0.309653
# 	trees: 289, Out-of-bag evaluation: accuracy:0.906651 logloss:0.310334
# 	trees: 299, Out-of-bag evaluation: accuracy:0.909429 logloss:0.309923
# 	trees: 300, Out-of-bag evaluation: accuracy:0.909862 logloss:0.309668

# %%
# Model features
model.make_inspector().features()
# Out:
# ["GrayLevelNonUniformity" (1; #0),
#  "GrayLevelNonUniformityNormalized" (1; #1),
#  "GrayLevelVariance" (1; #2),
#  "HighGrayLevelZoneEmphasis" (1; #3),
#  "LargeAreaEmphasis" (1; #4),
#  "LargeAreaHighGrayLevelEmphasis" (1; #5),
#  "LargeAreaLowGrayLevelEmphasis" (1; #6),
#  "LowGrayLevelZoneEmphasis" (1; #7),
#  "SizeZoneNonUniformity" (1; #8),
#  "SizeZoneNonUniformityNormalized" (1; #9),
#  "SmallAreaEmphasis" (1; #10),
#  "SmallAreaHighGrayLevelEmphasis" (1; #11),
#  "SmallAreaLowGrayLevelEmphasis" (1; #12),
#  "ZoneEntropy" (1; #13),
#  "ZonePercentage" (1; #14),
#  "ZoneVariance" (1; #15)]

# %%
# Feature importance
model.make_inspector().variable_importances()
# Out:
# {'INV_MEAN_MIN_DEPTH': [("HighGrayLevelZoneEmphasis" (1; #3),
#    0.2953645751142476),
#   ("SmallAreaLowGrayLevelEmphasis" (1; #12), 0.20774205804773666),
#   ("GrayLevelNonUniformity" (1; #0), 0.20363289801183743),
#   ("LargeAreaHighGrayLevelEmphasis" (1; #5), 0.20256618752593814),
#   ("LowGrayLevelZoneEmphasis" (1; #7), 0.2015608130052412),
#   ("SmallAreaHighGrayLevelEmphasis" (1; #11), 0.18792573838565182),
#   ("LargeAreaLowGrayLevelEmphasis" (1; #6), 0.16197682609377373),
#   ("GrayLevelVariance" (1; #2), 0.15850951038046918),
#   ("GrayLevelNonUniformityNormalized" (1; #1), 0.15590379281868388),
#   ("ZoneEntropy" (1; #13), 0.15056411483627755),
#   ("ZoneVariance" (1; #15), 0.14929803818185874),
#   ("LargeAreaEmphasis" (1; #4), 0.14800564060892857),
#   ("SmallAreaEmphasis" (1; #10), 0.14779259391137356),
#   ("ZonePercentage" (1; #14), 0.14752855255925096),
#   ("SizeZoneNonUniformityNormalized" (1; #9), 0.14500470744258045),
#   ("SizeZoneNonUniformity" (1; #8), 0.1446381229035811)],
#  'SUM_SCORE': [("HighGrayLevelZoneEmphasis" (1; #3), 66925.90107961772),
#   ("SmallAreaLowGrayLevelEmphasis" (1; #12), 36709.3328235133),
#   ("LowGrayLevelZoneEmphasis" (1; #7), 33163.80343754212),
#   ("GrayLevelNonUniformity" (1; #0), 25273.460311984792),
#   ("SmallAreaHighGrayLevelEmphasis" (1; #11), 23700.284006823105),
#   ("LargeAreaHighGrayLevelEmphasis" (1; #5), 22423.787114088856),
#   ("LargeAreaLowGrayLevelEmphasis" (1; #6), 8703.970227835855),
#   ("GrayLevelNonUniformityNormalized" (1; #1), 8286.129539688627),
#   ("GrayLevelVariance" (1; #2), 7683.8052579893365),
#   ("ZoneEntropy" (1; #13), 5663.79805757629),
#   ("ZoneVariance" (1; #15), 4642.910954588675),
#   ("LargeAreaEmphasis" (1; #4), 4134.077797613717),
#   ("SmallAreaEmphasis" (1; #10), 3772.2393624898004),
#   ("ZonePercentage" (1; #14), 3752.226095635154),
#   ("SizeZoneNonUniformityNormalized" (1; #9), 3444.2530095443576),
#   ("SizeZoneNonUniformity" (1; #8), 3139.8287269439293)],
#  'NUM_AS_ROOT': [("HighGrayLevelZoneEmphasis" (1; #3), 94.0),
#   ("SmallAreaLowGrayLevelEmphasis" (1; #12), 68.0),
#   ("LowGrayLevelZoneEmphasis" (1; #7), 60.0),
#   ("SmallAreaHighGrayLevelEmphasis" (1; #11), 33.0),
#   ("LargeAreaHighGrayLevelEmphasis" (1; #5), 23.0),
#   ("GrayLevelNonUniformity" (1; #0), 9.0),
#   ("LargeAreaLowGrayLevelEmphasis" (1; #6), 4.0),
#   ("SmallAreaEmphasis" (1; #10), 4.0),
#   ("SizeZoneNonUniformityNormalized" (1; #9), 3.0),
#   ("ZoneEntropy" (1; #13), 2.0)],
#  'NUM_NODES': [("LargeAreaHighGrayLevelEmphasis" (1; #5), 980.0),
#   ("GrayLevelNonUniformity" (1; #0), 960.0),
#   ("HighGrayLevelZoneEmphasis" (1; #3), 954.0),
#   ("SmallAreaLowGrayLevelEmphasis" (1; #12), 732.0),
#   ("LowGrayLevelZoneEmphasis" (1; #7), 684.0),
#   ("SmallAreaHighGrayLevelEmphasis" (1; #11), 671.0),
#   ("LargeAreaLowGrayLevelEmphasis" (1; #6), 636.0),
#   ("GrayLevelNonUniformityNormalized" (1; #1), 618.0),
#   ("GrayLevelVariance" (1; #2), 593.0),
#   ("ZoneEntropy" (1; #13), 508.0),
#   ("ZoneVariance" (1; #15), 462.0),
#   ("SmallAreaEmphasis" (1; #10), 416.0),
#   ("LargeAreaEmphasis" (1; #4), 413.0),
#   ("SizeZoneNonUniformityNormalized" (1; #9), 395.0),
#   ("SizeZoneNonUniformity" (1; #8), 378.0),
#   ("ZonePercentage" (1; #14), 369.0)]}

# %%
# Model self evaluation
model.make_inspector().evaluation()
# Out:
# Evaluation(num_examples=1336, accuracy=0.9098615931590345, loss=0.3096682434717621, rmse=None, ndcg=None, aucs=None, auuc=None, qini=None)

# %%
logs = model.make_inspector().training_logs()

plt.figure(figsize=(12, 4))
plt.subplot(1, 2, 1)
plt.plot([log.num_trees for log in logs], [log.evaluation.accuracy for log in logs])
plt.xlabel("Number of trees")
plt.ylabel("Accuracy (out-of-bag)")
plt.subplot(1, 2, 2)
plt.plot([log.num_trees for log in logs], [log.evaluation.loss for log in logs])
plt.xlabel("Number of trees")
plt.ylabel("Logloss (out-of-bag)")
plt.show()

# %% [markdown]
# Calculate the score of our hold-out validation dataset

# %%
predictions = model.predict(val_ds)
y_true      = validation_data["label"]

from sklearn.metrics import roc_auc_score
ROC_AUC = roc_auc_score(y_true, predictions)
print("The ROC AUC score is %.5f" % ROC_AUC )
# Out:
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 61ms/step
# The ROC AUC score is 0.97446

# %%
# Compute binary classification metrics with sklearn
import numpy as np
from sklearn.metrics import (
    accuracy_score,
    precision_score,
    recall_score,
    f1_score,
    roc_auc_score,
    average_precision_score,
    confusion_matrix,
    classification_report,
    matthews_corrcoef,
    log_loss,
    brier_score_loss,
)

# Get predictions (probabilities or class labels)
preds = model.predict(test_ds)
# If model outputs probabilities, convert to labels by threshold 0.5
if preds.ndim == 2:
    # For TFDF classification, preds may be class probabilities with shape (N, 2)
    if preds.shape[1] == 2:
        pos_probs = preds[:, 1]
    else:
        # If single-probability column (positive class)
        pos_probs = preds[:, -1]
    y_pred = (pos_probs >= 0.5).astype(int)
else:
    # Already class labels
    y_pred = preds.astype(int)
    pos_probs = None

# Ground truth labels (must be 0/1 integers)
y_true = test_data["label"].astype(int).to_numpy()

# Core metrics
metrics = {}
metrics["accuracy"] = accuracy_score(y_true, y_pred)
metrics["precision"] = precision_score(y_true, y_pred, zero_division=0)
metrics["recall"] = recall_score(y_true, y_pred, zero_division=0)
metrics["f1"] = f1_score(y_true, y_pred, zero_division=0)
metrics["mcc"] = matthews_corrcoef(y_true, y_pred)

# Probabilistic metrics (only if we have probabilities)
if pos_probs is not None:
    metrics["roc_auc"] = roc_auc_score(y_true, pos_probs)
    metrics["pr_auc"] = average_precision_score(y_true, pos_probs)
    metrics["log_loss"] = log_loss(y_true, pos_probs, labels=[0,1])
    metrics["brier_score"] = brier_score_loss(y_true, pos_probs)

# Confusion matrix and detailed report
cm = confusion_matrix(y_true, y_pred, labels=[0,1])
report = classification_report(y_true, y_pred, digits=4)

print("Sklearn binary metrics:")
for k, v in metrics.items():
    print(f"{k}: {v:.4f}")
print("\nConfusion matrix:\n", cm)
print("\nClassification report:\n", report)
# Out:
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 72ms/step
# Sklearn binary metrics:
# accuracy: 0.9607
# precision: 0.8393
# recall: 0.8868
# f1: 0.8624
# mcc: 0.8399
# roc_auc: 0.9869
# pr_auc: 0.9477
# log_loss: 0.1063
# brier_score: 0.0299
#
# Confusion matrix:
#  [[320   9]
#  [  6  47]]
#
# Classification report:
#                precision    recall  f1-score   support
#
#            0     0.9816    0.9726    0.9771       329
#            1     0.8393    0.8868    0.8624        53
#
#     accuracy                         0.9607       382
#    macro avg     0.9104    0.9297    0.9197       382
# weighted avg     0.9619    0.9607    0.9612       382
