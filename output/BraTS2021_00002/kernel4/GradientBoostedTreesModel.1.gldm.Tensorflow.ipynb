# %%
# Import packages and modules
import numpy  as np
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow_decision_forests as tfdf

from sklearn.model_selection import train_test_split
# Out:
# 2026-08-12 05:36:55.099686: I tensorflow/core/util/port.cc:113] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2026-08-12 05:36:55.463073: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2026-08-12 05:36:59.889376: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
# Check the version of TensorFlow Decision Forests
print("Found TensorFlow Decision Forests v" + tfdf.__version__)
# Out:
# Found TensorFlow Decision Forests v1.9.1

# %%
datasetPath = 'dataset/firstorder/kernel5-radius5/dataset.csv'

# %%
# Parameters
datasetPath = "dataset/gldm/kernel4/1.dataset.csv"

# %%
# train/validation/test = 70/10/20
dataset = pd.read_csv(datasetPath)

train_data, temp_data = train_test_split(dataset, test_size=0.3, random_state=42)
validation_data, test_data = train_test_split(temp_data, test_size=2/3, random_state=42)

# %%
from sklearn.utils.class_weight import compute_class_weight

# tinh class weight tren tap train
classes = np.array([0, 1])
weights = compute_class_weight(class_weight="balanced", classes=classes, y=train_data["label"])
class_weight = {0: weights[0], 1: weights[1]}

# gan sample_weight cho tung dong
train_data["sample_weight"] = train_data["label"].map(class_weight)
validation_data["sample_weight"] = validation_data["label"].map(class_weight)
test_data["sample_weight"] = test_data["label"].map(class_weight)

# Convert the dataset into a TensorFlow dataset.
train_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    train_data, label="label", weight="sample_weight"
)         
val_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    validation_data, label="label", weight="sample_weight"
)
test_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    test_data, label="label", weight="sample_weight"
)
# Out:
# 2026-08-12 05:37:14.857312: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:984] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2026-08-12 05:37:14.858787: W tensorflow/core/common_runtime/gpu/gpu_device.cc:2251] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...

# %%
import keras

# %%
# %%time

# Train a Gradient Boosted Trees model.
model = tfdf.keras.GradientBoostedTreesModel()

# Add evaluation metrics
model.compile(
    metrics=["accuracy"]
)
model.fit(x=train_ds)

# # Train a Gradient Boosted Trees model.
# model = tfdf.keras.GradientBoostedTreesModel(num_trees=1500)
# model.fit(train_ds)
# Out:
# Use /tmp/tmpj04baq36 as temporary training directory
# Reading training dataset...
# [WARNING 26-08-12 05:37:14.9907 UTC gradient_boosted_trees.cc:1840] "goss_alpha" set but "sampling_method" not equal to "GOSS".
# [WARNING 26-08-12 05:37:14.9909 UTC gradient_boosted_trees.cc:1851] "goss_beta" set but "sampling_method" not equal to "GOSS".
# [WARNING 26-08-12 05:37:14.9909 UTC gradient_boosted_trees.cc:1865] "selective_gradient_boosting_ratio" set but "sampling_method" not equal to "SELGB".
# Training dataset read in 0:00:02.483473. Found 1336 examples.
# Training model...
# Model trained in 0:00:00.232265
# Compiling model...
# [INFO 26-08-12 05:37:17.7326 UTC kernel.cc:1233] Loading model from path /tmp/tmpj04baq36/model/ with prefix cd054658224a4a03
# [INFO 26-08-12 05:37:17.7345 UTC quick_scorer_extended.cc:911] The binary was compiled without AVX2 support, but your CPU supports it. Enable it for faster model inference.
# [INFO 26-08-12 05:37:17.7346 UTC abstract_model.cc:1362] Engine "GradientBoostedTreesQuickScorerExtended" built
# [INFO 26-08-12 05:37:17.7346 UTC kernel.cc:1061] Use fast generic engine
# Model compiled.
# CPU times: user 5.8 s, sys: 302 ms, total: 6.1 s
# Wall time: 5.73 s

# %%
# Evaluate the model
evaluate = model.evaluate(val_ds, return_dict=True)
print()

for name, value in evaluate.items():
    print(f"{name}: {value:.4f}")
# Out:
# WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 1/1 [==============================] - ETA: 0s - loss: 0.0000e+00 - accuracy: 0.9529
# 1/1 [==============================] - 3s 3s/step - loss: 0.0000e+00 - accuracy: 0.9529
# loss: 0.0000
# accuracy: 0.9529

# %%
# Model Summary
model.summary()
# Out:
# Model: "gradient_boosted_trees_model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
# =================================================================
# Total params: 1 (1.00 Byte)
# Trainable params: 0 (0.00 Byte)
# Non-trainable params: 1 (1.00 Byte)
# _________________________________________________________________
# Type: "GRADIENT_BOOSTED_TREES"
# Task: CLASSIFICATION
# Label: "__LABEL"
#
# Input Features (14):
# 	DependenceEntropy
# 	DependenceNonUniformity
# 	DependenceNonUniformityNormalized
# 	DependenceVariance
# 	GrayLevelNonUniformity
# 	GrayLevelVariance
# 	HighGrayLevelEmphasis
# 	LargeDependenceEmphasis
# 	LargeDependenceHighGrayLevelEmphasis
# 	LargeDependenceLowGrayLevelEmphasis
# 	LowGrayLevelEmphasis
# 	SmallDependenceEmphasis
# 	SmallDependenceHighGrayLevelEmphasis
# 	SmallDependenceLowGrayLevelEmphasis
#
# Trained with weights
#
# Variable Importance: INV_MEAN_MIN_DEPTH:
#     1.                "HighGrayLevelEmphasis"  1.000000 ################
#     2. "LargeDependenceHighGrayLevelEmphasis"  0.286760 ##
#     3.                    "DependenceEntropy"  0.218730
#     4.  "SmallDependenceLowGrayLevelEmphasis"  0.196498
#     5.                 "LowGrayLevelEmphasis"  0.183333
#     6. "SmallDependenceHighGrayLevelEmphasis"  0.183322
#     7.                   "DependenceVariance"  0.182837
#     8.               "GrayLevelNonUniformity"  0.181888
#     9.              "SmallDependenceEmphasis"  0.181085
#    10.                    "GrayLevelVariance"  0.177539
#    11.  "LargeDependenceLowGrayLevelEmphasis"  0.175878
#    12.              "LargeDependenceEmphasis"  0.175315
#    13.    "DependenceNonUniformityNormalized"  0.175090
#    14.              "DependenceNonUniformity"  0.175006
#
# Variable Importance: NUM_AS_ROOT:
#     1. "HighGrayLevelEmphasis" 21.000000
#
# Variable Importance: NUM_NODES:
#     1. "LargeDependenceHighGrayLevelEmphasis" 102.000000 ################
#     2.                "HighGrayLevelEmphasis" 98.000000 ###############
#     3.                    "DependenceEntropy" 60.000000 #########
#     4.  "SmallDependenceLowGrayLevelEmphasis" 42.000000 ######
#     5.                 "LowGrayLevelEmphasis" 39.000000 #####
#     6. "SmallDependenceHighGrayLevelEmphasis" 36.000000 #####
#     7.              "SmallDependenceEmphasis" 30.000000 ####
#     8.               "GrayLevelNonUniformity" 27.000000 ###
#     9.                   "DependenceVariance" 25.000000 ###
#    10.                    "GrayLevelVariance" 17.000000 #
#    11.  "LargeDependenceLowGrayLevelEmphasis" 14.000000 #
#    12.              "LargeDependenceEmphasis"  9.000000
#    13.    "DependenceNonUniformityNormalized"  7.000000
#    14.              "DependenceNonUniformity"  5.000000
#
# Variable Importance: SUM_SCORE:
#     1.                "HighGrayLevelEmphasis" 1192.649762 ################
#     2. "LargeDependenceHighGrayLevelEmphasis" 151.324530 ##
#     3.                    "DependenceEntropy" 143.546385 #
#     4. "SmallDependenceHighGrayLevelEmphasis" 21.252798
#     5.               "GrayLevelNonUniformity" 15.054245
#     6.                 "LowGrayLevelEmphasis" 10.236483
#     7.  "SmallDependenceLowGrayLevelEmphasis"  8.463621
#     8.                    "GrayLevelVariance"  6.912208
#     9.              "LargeDependenceEmphasis"  6.781115
#    10.                   "DependenceVariance"  5.397313
#    11.  "LargeDependenceLowGrayLevelEmphasis"  4.092817
#    12.              "SmallDependenceEmphasis"  3.672743
#    13.    "DependenceNonUniformityNormalized"  2.851007
#    14.              "DependenceNonUniformity"  1.750643
#
#
#
# Loss: BINOMIAL_LOG_LIKELIHOOD
# Validation loss value: 0.506106
# Number of trees per iteration: 1
# Node format: NOT_SET
# Number of trees: 21
# Total number of nodes: 1043
#
# Number of nodes by tree:
# Count: 21 Average: 49.6667 StdDev: 2.71387
# Min: 43 Max: 55 Ignored: 0
# ----------------------------------------------
# [ 43, 44)  1   4.76%   4.76% #
# [ 44, 45)  0   0.00%   4.76%
# [ 45, 46)  2   9.52%  14.29% ##
# [ 46, 47)  0   0.00%  14.29%
# [ 47, 48)  1   4.76%  19.05% #
# [ 48, 49)  0   0.00%  19.05%
# [ 49, 50)  5  23.81%  42.86% #####
# [ 50, 51)  0   0.00%  42.86%
# [ 51, 52) 10  47.62%  90.48% ##########
# [ 52, 53)  0   0.00%  90.48%
# [ 53, 54)  1   4.76%  95.24% #
# [ 54, 55)  0   0.00%  95.24%
# [ 55, 55]  1   4.76% 100.00% #
#
# Depth by leafs:
# Count: 532 Average: 4.74624 StdDev: 0.456248
# Min: 3 Max: 5 Ignored: 0
# ----------------------------------------------
# [ 3, 4)   5   0.94%   0.94%
# [ 4, 5) 125  23.50%  24.44% ###
# [ 5, 5] 402  75.56% 100.00% ##########
#
# Number of training obs by leaf:
# Count: 532 Average: 48.4737 StdDev: 128.812
# Min: 5 Max: 744 Ignored: 0
# ----------------------------------------------
# [   5,  42) 400  75.19%  75.19% ##########
# [  42,  79)  80  15.04%  90.23% ##
# [  79, 116)  22   4.14%  94.36% #
# [ 116, 153)   4   0.75%  95.11%
# [ 153, 190)   4   0.75%  95.86%
# [ 190, 227)   0   0.00%  95.86%
# [ 227, 264)   0   0.00%  95.86%
# [ 264, 301)   1   0.19%  96.05%
# [ 301, 338)   0   0.00%  96.05%
# [ 338, 375)   0   0.00%  96.05%
# [ 375, 412)   0   0.00%  96.05%
# [ 412, 449)   0   0.00%  96.05%
# [ 449, 486)   0   0.00%  96.05%
# [ 486, 523)   1   0.19%  96.24%
# [ 523, 560)   0   0.00%  96.24%
# [ 560, 597)   6   1.13%  97.37%
# [ 597, 634)   1   0.19%  97.56%
# [ 634, 671)   1   0.19%  97.74%
# [ 671, 708)   2   0.38%  98.12%
# [ 708, 744]  10   1.88% 100.00%
#
# Attribute in nodes:
# 	102 : LargeDependenceHighGrayLevelEmphasis [NUMERICAL]
# 	98 : HighGrayLevelEmphasis [NUMERICAL]
# 	60 : DependenceEntropy [NUMERICAL]
# 	42 : SmallDependenceLowGrayLevelEmphasis [NUMERICAL]
# 	39 : LowGrayLevelEmphasis [NUMERICAL]
# 	36 : SmallDependenceHighGrayLevelEmphasis [NUMERICAL]
# 	30 : SmallDependenceEmphasis [NUMERICAL]
# 	27 : GrayLevelNonUniformity [NUMERICAL]
# 	25 : DependenceVariance [NUMERICAL]
# 	17 : GrayLevelVariance [NUMERICAL]
# 	14 : LargeDependenceLowGrayLevelEmphasis [NUMERICAL]
# 	9 : LargeDependenceEmphasis [NUMERICAL]
# 	7 : DependenceNonUniformityNormalized [NUMERICAL]
# 	5 : DependenceNonUniformity [NUMERICAL]
#
# Attribute in nodes with depth <= 0:
# 	21 : HighGrayLevelEmphasis [NUMERICAL]
#
# Attribute in nodes with depth <= 1:
# 	42 : HighGrayLevelEmphasis [NUMERICAL]
# 	21 : LargeDependenceHighGrayLevelEmphasis [NUMERICAL]
#
# Attribute in nodes with depth <= 2:
# 	49 : HighGrayLevelEmphasis [NUMERICAL]
# 	40 : LargeDependenceHighGrayLevelEmphasis [NUMERICAL]
# 	30 : DependenceEntropy [NUMERICAL]
# 	15 : SmallDependenceLowGrayLevelEmphasis [NUMERICAL]
# 	5 : DependenceVariance [NUMERICAL]
# 	3 : SmallDependenceEmphasis [NUMERICAL]
# 	2 : LowGrayLevelEmphasis [NUMERICAL]
# 	2 : GrayLevelNonUniformity [NUMERICAL]
# 	1 : GrayLevelVariance [NUMERICAL]
#
# Attribute in nodes with depth <= 3:
# 	76 : HighGrayLevelEmphasis [NUMERICAL]
# 	64 : LargeDependenceHighGrayLevelEmphasis [NUMERICAL]
# 	45 : DependenceEntropy [NUMERICAL]
# 	33 : SmallDependenceLowGrayLevelEmphasis [NUMERICAL]
# 	24 : SmallDependenceHighGrayLevelEmphasis [NUMERICAL]
# 	19 : LowGrayLevelEmphasis [NUMERICAL]
# 	12 : GrayLevelNonUniformity [NUMERICAL]
# 	9 : SmallDependenceEmphasis [NUMERICAL]
# 	9 : DependenceVariance [NUMERICAL]
# 	7 : GrayLevelVariance [NUMERICAL]
# 	4 : LargeDependenceLowGrayLevelEmphasis [NUMERICAL]
# 	3 : DependenceNonUniformityNormalized [NUMERICAL]
# 	3 : DependenceNonUniformity [NUMERICAL]
# 	2 : LargeDependenceEmphasis [NUMERICAL]
#
# Attribute in nodes with depth <= 5:
# 	102 : LargeDependenceHighGrayLevelEmphasis [NUMERICAL]
# 	98 : HighGrayLevelEmphasis [NUMERICAL]
# 	60 : DependenceEntropy [NUMERICAL]
# 	42 : SmallDependenceLowGrayLevelEmphasis [NUMERICAL]
# 	39 : LowGrayLevelEmphasis [NUMERICAL]
# 	36 : SmallDependenceHighGrayLevelEmphasis [NUMERICAL]
# 	30 : SmallDependenceEmphasis [NUMERICAL]
# 	27 : GrayLevelNonUniformity [NUMERICAL]
# 	25 : DependenceVariance [NUMERICAL]
# 	17 : GrayLevelVariance [NUMERICAL]
# 	14 : LargeDependenceLowGrayLevelEmphasis [NUMERICAL]
# 	9 : LargeDependenceEmphasis [NUMERICAL]
# 	7 : DependenceNonUniformityNormalized [NUMERICAL]
# 	5 : DependenceNonUniformity [NUMERICAL]
#
# Condition type in nodes:
# 	511 : HigherCondition
# Condition type in nodes with depth <= 0:
# 	21 : HigherCondition
# Condition type in nodes with depth <= 1:
# 	63 : HigherCondition
# Condition type in nodes with depth <= 2:
# 	147 : HigherCondition
# Condition type in nodes with depth <= 3:
# 	310 : HigherCondition
# Condition type in nodes with depth <= 5:
# 	511 : HigherCondition
#
# Training logs:
# Number of iteration to final model: 21
# 	Iter:1 train-loss:1.209559 valid-loss:1.225798  train-accuracy:0.975175 valid-accuracy:0.937833
# 	Iter:2 train-loss:1.062376 valid-loss:1.103249  train-accuracy:0.983291 valid-accuracy:0.911835
# 	Iter:3 train-loss:0.939204 valid-loss:1.002712  train-accuracy:0.982353 valid-accuracy:0.911835
# 	Iter:4 train-loss:0.835634 valid-loss:0.918628  train-accuracy:0.983306 valid-accuracy:0.911835
# 	Iter:5 train-loss:0.746470 valid-loss:0.851385  train-accuracy:0.988087 valid-accuracy:0.911835
# 	Iter:6 train-loss:0.668837 valid-loss:0.794759  train-accuracy:0.988563 valid-accuracy:0.911835
# 	Iter:16 train-loss:0.261405 valid-loss:0.522902  train-accuracy:0.991422 valid-accuracy:0.911835
# 	Iter:26 train-loss:0.120205 valid-loss:0.518538  train-accuracy:0.994758 valid-accuracy:0.911835
# 	Iter:36 train-loss:0.066607 valid-loss:0.578062  train-accuracy:0.996188 valid-accuracy:0.911835
# 	Iter:46 train-loss:0.042135 valid-loss:0.611733  train-accuracy:0.998094 valid-accuracy:0.880670

# %%
# Model features
model.make_inspector().features()
# Out:
# ["DependenceEntropy" (1; #0),
#  "DependenceNonUniformity" (1; #1),
#  "DependenceNonUniformityNormalized" (1; #2),
#  "DependenceVariance" (1; #3),
#  "GrayLevelNonUniformity" (1; #4),
#  "GrayLevelVariance" (1; #5),
#  "HighGrayLevelEmphasis" (1; #6),
#  "LargeDependenceEmphasis" (1; #7),
#  "LargeDependenceHighGrayLevelEmphasis" (1; #8),
#  "LargeDependenceLowGrayLevelEmphasis" (1; #9),
#  "LowGrayLevelEmphasis" (1; #10),
#  "SmallDependenceEmphasis" (1; #11),
#  "SmallDependenceHighGrayLevelEmphasis" (1; #12),
#  "SmallDependenceLowGrayLevelEmphasis" (1; #13)]

# %%
# Feature importance
model.make_inspector().variable_importances()
# Out:
# {'INV_MEAN_MIN_DEPTH': [("HighGrayLevelEmphasis" (1; #6), 1.0),
#   ("LargeDependenceHighGrayLevelEmphasis" (1; #8), 0.2867600532379416),
#   ("DependenceEntropy" (1; #0), 0.21873044254810878),
#   ("SmallDependenceLowGrayLevelEmphasis" (1; #13), 0.19649785722164373),
#   ("LowGrayLevelEmphasis" (1; #10), 0.1833333944196955),
#   ("SmallDependenceHighGrayLevelEmphasis" (1; #12), 0.18332181664869843),
#   ("DependenceVariance" (1; #3), 0.1828369634727024),
#   ("GrayLevelNonUniformity" (1; #4), 0.18188753972449656),
#   ("SmallDependenceEmphasis" (1; #11), 0.18108502296611043),
#   ("GrayLevelVariance" (1; #5), 0.17753892457447049),
#   ("LargeDependenceLowGrayLevelEmphasis" (1; #9), 0.17587845264727586),
#   ("LargeDependenceEmphasis" (1; #7), 0.17531501573019545),
#   ("DependenceNonUniformityNormalized" (1; #2), 0.17509046477523538),
#   ("DependenceNonUniformity" (1; #1), 0.17500590752846593)],
#  'NUM_AS_ROOT': [("HighGrayLevelEmphasis" (1; #6), 21.0)],
#  'SUM_SCORE': [("HighGrayLevelEmphasis" (1; #6), 1192.6497622260113),
#   ("LargeDependenceHighGrayLevelEmphasis" (1; #8), 151.32452957162013),
#   ("DependenceEntropy" (1; #0), 143.54638510520473),
#   ("SmallDependenceHighGrayLevelEmphasis" (1; #12), 21.2527982710905),
#   ("GrayLevelNonUniformity" (1; #4), 15.054245004085708),
#   ("LowGrayLevelEmphasis" (1; #10), 10.236483100325815),
#   ("SmallDependenceLowGrayLevelEmphasis" (1; #13), 8.463620975224428),
#   ("GrayLevelVariance" (1; #5), 6.912207568910568),
#   ("LargeDependenceEmphasis" (1; #7), 6.781115176707491),
#   ("DependenceVariance" (1; #3), 5.397312520722558),
#   ("LargeDependenceLowGrayLevelEmphasis" (1; #9), 4.092817263270281),
#   ("SmallDependenceEmphasis" (1; #11), 3.67274334976982),
#   ("DependenceNonUniformityNormalized" (1; #2), 2.8510074571425137),
#   ("DependenceNonUniformity" (1; #1), 1.7506429760653806)],
#  'NUM_NODES': [("LargeDependenceHighGrayLevelEmphasis" (1; #8), 102.0),
#   ("HighGrayLevelEmphasis" (1; #6), 98.0),
#   ("DependenceEntropy" (1; #0), 60.0),
#   ("SmallDependenceLowGrayLevelEmphasis" (1; #13), 42.0),
#   ("LowGrayLevelEmphasis" (1; #10), 39.0),
#   ("SmallDependenceHighGrayLevelEmphasis" (1; #12), 36.0),
#   ("SmallDependenceEmphasis" (1; #11), 30.0),
#   ("GrayLevelNonUniformity" (1; #4), 27.0),
#   ("DependenceVariance" (1; #3), 25.0),
#   ("GrayLevelVariance" (1; #5), 17.0),
#   ("LargeDependenceLowGrayLevelEmphasis" (1; #9), 14.0),
#   ("LargeDependenceEmphasis" (1; #7), 9.0),
#   ("DependenceNonUniformityNormalized" (1; #2), 7.0),
#   ("DependenceNonUniformity" (1; #1), 5.0)]}

# %%
# Model self evaluation
model.make_inspector().evaluation()
# Out:
# Evaluation(num_examples=None, accuracy=0.9118350744247437, loss=0.5061061382293701, rmse=None, ndcg=None, aucs=None, auuc=None, qini=None)

# %%
logs = model.make_inspector().training_logs()

plt.figure(figsize=(12, 4))
plt.subplot(1, 2, 1)
plt.plot([log.num_trees for log in logs], [log.evaluation.accuracy for log in logs])
plt.xlabel("Number of trees")
plt.ylabel("Accuracy (out-of-bag)")
plt.subplot(1, 2, 2)
plt.plot([log.num_trees for log in logs], [log.evaluation.loss for log in logs])
plt.xlabel("Number of trees")
plt.ylabel("Logloss (out-of-bag)")
plt.show()

# %% [markdown]
# Calculate the score of our hold-out validation dataset

# %%
predictions = model.predict(val_ds)
y_true      = validation_data["label"]

from sklearn.metrics import roc_auc_score
ROC_AUC = roc_auc_score(y_true, predictions)
print("The ROC AUC score is %.5f" % ROC_AUC )
# Out:
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 52ms/step
# The ROC AUC score is 0.99079

# %%
# Compute binary classification metrics with sklearn
import numpy as np
from sklearn.metrics import (
    accuracy_score,
    precision_score,
    recall_score,
    f1_score,
    roc_auc_score,
    average_precision_score,
    confusion_matrix,
    classification_report,
    matthews_corrcoef,
    log_loss,
    brier_score_loss,
)

# Get predictions (probabilities or class labels)
preds = model.predict(test_ds)
# If model outputs probabilities, convert to labels by threshold 0.5
if preds.ndim == 2:
    # For TFDF classification, preds may be class probabilities with shape (N, 2)
    if preds.shape[1] == 2:
        pos_probs = preds[:, 1]
    else:
        # If single-probability column (positive class)
        pos_probs = preds[:, -1]
    y_pred = (pos_probs >= 0.5).astype(int)
else:
    # Already class labels
    y_pred = preds.astype(int)
    pos_probs = None

# Ground truth labels (must be 0/1 integers)
y_true = test_data["label"].astype(int).to_numpy()

# Core metrics
metrics = {}
metrics["accuracy"] = accuracy_score(y_true, y_pred)
metrics["precision"] = precision_score(y_true, y_pred, zero_division=0)
metrics["recall"] = recall_score(y_true, y_pred, zero_division=0)
metrics["f1"] = f1_score(y_true, y_pred, zero_division=0)
metrics["mcc"] = matthews_corrcoef(y_true, y_pred)

# Probabilistic metrics (only if we have probabilities)
if pos_probs is not None:
    metrics["roc_auc"] = roc_auc_score(y_true, pos_probs)
    metrics["pr_auc"] = average_precision_score(y_true, pos_probs)
    metrics["log_loss"] = log_loss(y_true, pos_probs, labels=[0,1])
    metrics["brier_score"] = brier_score_loss(y_true, pos_probs)

# Confusion matrix and detailed report
cm = confusion_matrix(y_true, y_pred, labels=[0,1])
report = classification_report(y_true, y_pred, digits=4)

print("Sklearn binary metrics:")
for k, v in metrics.items():
    print(f"{k}: {v:.4f}")
print("\nConfusion matrix:\n", cm)
print("\nClassification report:\n", report)
# Out:
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 58ms/step
# Sklearn binary metrics:
# accuracy: 0.9503
# precision: 0.7556
# recall: 0.8095
# f1: 0.7816
# mcc: 0.7542
# roc_auc: 0.9560
# pr_auc: 0.8769
# log_loss: 0.1638
# brier_score: 0.0402
#
# Confusion matrix:
#  [[329  11]
#  [  8  34]]
#
# Classification report:
#                precision    recall  f1-score   support
#
#            0     0.9763    0.9676    0.9719       340
#            1     0.7556    0.8095    0.7816        42
#
#     accuracy                         0.9503       382
#    macro avg     0.8659    0.8886    0.8768       382
# weighted avg     0.9520    0.9503    0.9510       382
