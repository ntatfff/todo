# %%
# Import packages and modules
import numpy  as np
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow_decision_forests as tfdf

from sklearn.model_selection import train_test_split
# Out:
# 2026-08-12 05:38:05.756169: I tensorflow/core/util/port.cc:113] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2026-08-12 05:38:06.088994: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2026-08-12 05:38:13.155927: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
# Check the version of TensorFlow Decision Forests
print("Found TensorFlow Decision Forests v" + tfdf.__version__)
# Out:
# Found TensorFlow Decision Forests v1.9.1

# %%
datasetPath = 'dataset/firstorder/kernel5-radius5/dataset.csv'

# %%
# Parameters
datasetPath = "dataset/glszm/kernel4/1.dataset.csv"

# %%
# train/validation/test = 70/10/20
dataset = pd.read_csv(datasetPath)

train_data, temp_data = train_test_split(dataset, test_size=0.3, random_state=42)
validation_data, test_data = train_test_split(temp_data, test_size=2/3, random_state=42)

# %%
from sklearn.utils.class_weight import compute_class_weight

# tinh class weight tren tap train
classes = np.array([0, 1])
weights = compute_class_weight(class_weight="balanced", classes=classes, y=train_data["label"])
class_weight = {0: weights[0], 1: weights[1]}

# gan sample_weight cho tung dong
train_data["sample_weight"] = train_data["label"].map(class_weight)
validation_data["sample_weight"] = validation_data["label"].map(class_weight)
test_data["sample_weight"] = test_data["label"].map(class_weight)

# Convert the dataset into a TensorFlow dataset.
train_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    train_data, label="label", weight="sample_weight"
)         
val_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    validation_data, label="label", weight="sample_weight"
)
test_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    test_data, label="label", weight="sample_weight"
)
# Out:
# 2026-08-12 05:38:25.056861: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:984] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2026-08-12 05:38:25.058289: W tensorflow/core/common_runtime/gpu/gpu_device.cc:2251] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...

# %%
import keras

# %%
# %%time

# Train a Gradient Boosted Trees model.
model = tfdf.keras.GradientBoostedTreesModel()

# Add evaluation metrics
model.compile(
    metrics=["accuracy"]
)
model.fit(x=train_ds)

# # Train a Gradient Boosted Trees model.
# model = tfdf.keras.GradientBoostedTreesModel(num_trees=1500)
# model.fit(train_ds)
# Out:
# Use /tmp/tmpxslar93c as temporary training directory
# Reading training dataset...
# [WARNING 26-08-12 05:38:25.1902 UTC gradient_boosted_trees.cc:1840] "goss_alpha" set but "sampling_method" not equal to "GOSS".
# [WARNING 26-08-12 05:38:25.1905 UTC gradient_boosted_trees.cc:1851] "goss_beta" set but "sampling_method" not equal to "GOSS".
# [WARNING 26-08-12 05:38:25.1905 UTC gradient_boosted_trees.cc:1865] "selective_gradient_boosting_ratio" set but "sampling_method" not equal to "SELGB".
# Training dataset read in 0:00:02.400749. Found 1336 examples.
# Training model...
# Model trained in 0:00:00.383122
# Compiling model...
# [INFO 26-08-12 05:38:27.9984 UTC kernel.cc:1233] Loading model from path /tmp/tmpxslar93c/model/ with prefix 323316dd0294413e
# [INFO 26-08-12 05:38:28.0020 UTC quick_scorer_extended.cc:911] The binary was compiled without AVX2 support, but your CPU supports it. Enable it for faster model inference.
# [INFO 26-08-12 05:38:28.0022 UTC abstract_model.cc:1362] Engine "GradientBoostedTreesQuickScorerExtended" built
# [INFO 26-08-12 05:38:28.0022 UTC kernel.cc:1061] Use fast generic engine
# Model compiled.
# CPU times: user 5.87 s, sys: 558 ms, total: 6.42 s
# Wall time: 5.72 s

# %%
# Evaluate the model
evaluate = model.evaluate(val_ds, return_dict=True)
print()

for name, value in evaluate.items():
    print(f"{name}: {value:.4f}")
# Out:
# WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 1/1 [==============================] - ETA: 0s - loss: 0.0000e+00 - accuracy: 0.9424
# 1/1 [==============================] - 3s 3s/step - loss: 0.0000e+00 - accuracy: 0.9424
# loss: 0.0000
# accuracy: 0.9424

# %%
# Model Summary
model.summary()
# Out:
# Model: "gradient_boosted_trees_model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
# =================================================================
# Total params: 1 (1.00 Byte)
# Trainable params: 0 (0.00 Byte)
# Non-trainable params: 1 (1.00 Byte)
# _________________________________________________________________
# Type: "GRADIENT_BOOSTED_TREES"
# Task: CLASSIFICATION
# Label: "__LABEL"
#
# Input Features (16):
# 	GrayLevelNonUniformity
# 	GrayLevelNonUniformityNormalized
# 	GrayLevelVariance
# 	HighGrayLevelZoneEmphasis
# 	LargeAreaEmphasis
# 	LargeAreaHighGrayLevelEmphasis
# 	LargeAreaLowGrayLevelEmphasis
# 	LowGrayLevelZoneEmphasis
# 	SizeZoneNonUniformity
# 	SizeZoneNonUniformityNormalized
# 	SmallAreaEmphasis
# 	SmallAreaHighGrayLevelEmphasis
# 	SmallAreaLowGrayLevelEmphasis
# 	ZoneEntropy
# 	ZonePercentage
# 	ZoneVariance
#
# Trained with weights
#
# Variable Importance: INV_MEAN_MIN_DEPTH:
#     1.        "HighGrayLevelZoneEmphasis"  0.363519 ################
#     2.   "LargeAreaHighGrayLevelEmphasis"  0.251131 ######
#     3.    "SmallAreaLowGrayLevelEmphasis"  0.228584 ####
#     4.           "GrayLevelNonUniformity"  0.228215 ####
#     5.   "SmallAreaHighGrayLevelEmphasis"  0.208502 ##
#     6.    "LargeAreaLowGrayLevelEmphasis"  0.207122 ##
#     7.         "LowGrayLevelZoneEmphasis"  0.198244 #
#     8. "GrayLevelNonUniformityNormalized"  0.187752
#     9.                      "ZoneEntropy"  0.187016
#    10.                "GrayLevelVariance"  0.185542
#    11.                   "ZonePercentage"  0.184827
#    12.  "SizeZoneNonUniformityNormalized"  0.182558
#    13.                     "ZoneVariance"  0.182453
#    14.                "SmallAreaEmphasis"  0.180660
#    15.            "SizeZoneNonUniformity"  0.178223
#    16.                "LargeAreaEmphasis"  0.177941
#
# Variable Importance: NUM_AS_ROOT:
#     1.      "HighGrayLevelZoneEmphasis" 34.000000 ################
#     2.  "SmallAreaLowGrayLevelEmphasis"  8.000000 ###
#     3. "LargeAreaHighGrayLevelEmphasis"  7.000000 ##
#     4. "SmallAreaHighGrayLevelEmphasis"  6.000000 ##
#     5.       "LowGrayLevelZoneEmphasis"  3.000000
#     6.  "LargeAreaLowGrayLevelEmphasis"  2.000000
#
# Variable Importance: NUM_NODES:
#     1.        "HighGrayLevelZoneEmphasis" 196.000000 ################
#     2.           "GrayLevelNonUniformity" 156.000000 ############
#     3.   "LargeAreaHighGrayLevelEmphasis" 138.000000 ##########
#     4.    "SmallAreaLowGrayLevelEmphasis" 135.000000 ##########
#     5.    "LargeAreaLowGrayLevelEmphasis" 123.000000 #########
#     6.   "SmallAreaHighGrayLevelEmphasis" 102.000000 #######
#     7. "GrayLevelNonUniformityNormalized" 74.000000 #####
#     8.         "LowGrayLevelZoneEmphasis" 72.000000 #####
#     9.                      "ZoneEntropy" 56.000000 ###
#    10.                "GrayLevelVariance" 55.000000 ###
#    11.                   "ZonePercentage" 39.000000 ##
#    12.                     "ZoneVariance" 39.000000 ##
#    13.  "SizeZoneNonUniformityNormalized" 35.000000 #
#    14.                "SmallAreaEmphasis" 26.000000 #
#    15.            "SizeZoneNonUniformity" 21.000000
#    16.                "LargeAreaEmphasis" 13.000000
#
# Variable Importance: SUM_SCORE:
#     1.        "HighGrayLevelZoneEmphasis" 931.794967 ################
#     2.           "GrayLevelNonUniformity" 283.880860 ####
#     3.    "LargeAreaLowGrayLevelEmphasis" 79.910754 #
#     4. "GrayLevelNonUniformityNormalized" 55.144495
#     5.   "LargeAreaHighGrayLevelEmphasis" 45.770164
#     6.         "LowGrayLevelZoneEmphasis" 43.671634
#     7.   "SmallAreaHighGrayLevelEmphasis" 34.265024
#     8.    "SmallAreaLowGrayLevelEmphasis" 33.839043
#     9.                "SmallAreaEmphasis" 21.181686
#    10.                   "ZonePercentage" 17.266794
#    11.  "SizeZoneNonUniformityNormalized" 16.492663
#    12.                "GrayLevelVariance" 12.566291
#    13.                      "ZoneEntropy" 12.291934
#    14.                     "ZoneVariance" 11.548310
#    15.                "LargeAreaEmphasis"  1.455011
#    16.            "SizeZoneNonUniformity"  1.413188
#
#
#
# Loss: BINOMIAL_LOG_LIKELIHOOD
# Validation loss value: 0.510704
# Number of trees per iteration: 1
# Node format: NOT_SET
# Number of trees: 60
# Total number of nodes: 2620
#
# Number of nodes by tree:
# Count: 60 Average: 43.6667 StdDev: 7.07735
# Min: 27 Max: 59 Ignored: 0
# ----------------------------------------------
# [ 27, 28) 2   3.33%   3.33% ##
# [ 28, 30) 1   1.67%   5.00% #
# [ 30, 31) 0   0.00%   5.00%
# [ 31, 33) 0   0.00%   5.00%
# [ 33, 35) 0   0.00%   5.00%
# [ 35, 36) 9  15.00%  20.00% ##########
# [ 36, 38) 3   5.00%  25.00% ###
# [ 38, 40) 0   0.00%  25.00%
# [ 40, 41) 0   0.00%  25.00%
# [ 41, 43) 7  11.67%  36.67% ########
# [ 43, 45) 9  15.00%  51.67% ##########
# [ 45, 46) 5   8.33%  60.00% ######
# [ 46, 48) 8  13.33%  73.33% #########
# [ 48, 50) 3   5.00%  78.33% ###
# [ 50, 51) 0   0.00%  78.33%
# [ 51, 53) 4   6.67%  85.00% ####
# [ 53, 55) 7  11.67%  96.67% ########
# [ 55, 56) 1   1.67%  98.33% #
# [ 56, 58) 0   0.00%  98.33%
# [ 58, 59] 1   1.67% 100.00% #
#
# Depth by leafs:
# Count: 1340 Average: 4.68582 StdDev: 0.653767
# Min: 2 Max: 5 Ignored: 0
# ----------------------------------------------
# [ 2, 3)   17   1.27%   1.27%
# [ 3, 4)   91   6.79%   8.06% #
# [ 4, 5)  188  14.03%  22.09% ##
# [ 5, 5] 1044  77.91% 100.00% ##########
#
# Number of training obs by leaf:
# Count: 1340 Average: 54.9851 StdDev: 119.15
# Min: 5 Max: 825 Ignored: 0
# ----------------------------------------------
# [   5,  46) 1039  77.54%  77.54% ##########
# [  46,  87)  116   8.66%  86.19% #
# [  87, 128)   43   3.21%  89.40%
# [ 128, 169)   27   2.01%  91.42%
# [ 169, 210)   25   1.87%  93.28%
# [ 210, 251)   10   0.75%  94.03%
# [ 251, 292)    9   0.67%  94.70%
# [ 292, 333)    5   0.37%  95.07%
# [ 333, 374)    5   0.37%  95.45%
# [ 374, 415)    7   0.52%  95.97%
# [ 415, 456)    4   0.30%  96.27%
# [ 456, 497)   15   1.12%  97.39%
# [ 497, 538)   12   0.90%  98.28%
# [ 538, 579)    4   0.30%  98.58%
# [ 579, 620)    5   0.37%  98.96%
# [ 620, 661)    4   0.30%  99.25%
# [ 661, 702)    4   0.30%  99.55%
# [ 702, 743)    4   0.30%  99.85%
# [ 743, 784)    1   0.07%  99.93%
# [ 784, 825]    1   0.07% 100.00%
#
# Attribute in nodes:
# 	196 : HighGrayLevelZoneEmphasis [NUMERICAL]
# 	156 : GrayLevelNonUniformity [NUMERICAL]
# 	138 : LargeAreaHighGrayLevelEmphasis [NUMERICAL]
# 	135 : SmallAreaLowGrayLevelEmphasis [NUMERICAL]
# 	123 : LargeAreaLowGrayLevelEmphasis [NUMERICAL]
# 	102 : SmallAreaHighGrayLevelEmphasis [NUMERICAL]
# 	74 : GrayLevelNonUniformityNormalized [NUMERICAL]
# 	72 : LowGrayLevelZoneEmphasis [NUMERICAL]
# 	56 : ZoneEntropy [NUMERICAL]
# 	55 : GrayLevelVariance [NUMERICAL]
# 	39 : ZoneVariance [NUMERICAL]
# 	39 : ZonePercentage [NUMERICAL]
# 	35 : SizeZoneNonUniformityNormalized [NUMERICAL]
# 	26 : SmallAreaEmphasis [NUMERICAL]
# 	21 : SizeZoneNonUniformity [NUMERICAL]
# 	13 : LargeAreaEmphasis [NUMERICAL]
#
# Attribute in nodes with depth <= 0:
# 	34 : HighGrayLevelZoneEmphasis [NUMERICAL]
# 	8 : SmallAreaLowGrayLevelEmphasis [NUMERICAL]
# 	7 : LargeAreaHighGrayLevelEmphasis [NUMERICAL]
# 	6 : SmallAreaHighGrayLevelEmphasis [NUMERICAL]
# 	3 : LowGrayLevelZoneEmphasis [NUMERICAL]
# 	2 : LargeAreaLowGrayLevelEmphasis [NUMERICAL]
#
# Attribute in nodes with depth <= 1:
# 	55 : HighGrayLevelZoneEmphasis [NUMERICAL]
# 	28 : LargeAreaHighGrayLevelEmphasis [NUMERICAL]
# 	27 : GrayLevelNonUniformity [NUMERICAL]
# 	22 : SmallAreaLowGrayLevelEmphasis [NUMERICAL]
# 	18 : SmallAreaHighGrayLevelEmphasis [NUMERICAL]
# 	7 : LowGrayLevelZoneEmphasis [NUMERICAL]
# 	7 : LargeAreaLowGrayLevelEmphasis [NUMERICAL]
# 	4 : ZonePercentage [NUMERICAL]
# 	4 : GrayLevelNonUniformityNormalized [NUMERICAL]
# 	2 : ZoneVariance [NUMERICAL]
# 	2 : ZoneEntropy [NUMERICAL]
# 	2 : SmallAreaEmphasis [NUMERICAL]
# 	2 : GrayLevelVariance [NUMERICAL]
#
# Attribute in nodes with depth <= 2:
# 	78 : HighGrayLevelZoneEmphasis [NUMERICAL]
# 	64 : LargeAreaHighGrayLevelEmphasis [NUMERICAL]
# 	54 : GrayLevelNonUniformity [NUMERICAL]
# 	48 : SmallAreaLowGrayLevelEmphasis [NUMERICAL]
# 	37 : SmallAreaHighGrayLevelEmphasis [NUMERICAL]
# 	30 : LargeAreaLowGrayLevelEmphasis [NUMERICAL]
# 	26 : LowGrayLevelZoneEmphasis [NUMERICAL]
# 	13 : ZoneEntropy [NUMERICAL]
# 	13 : GrayLevelNonUniformityNormalized [NUMERICAL]
# 	10 : SizeZoneNonUniformityNormalized [NUMERICAL]
# 	10 : GrayLevelVariance [NUMERICAL]
# 	9 : ZonePercentage [NUMERICAL]
# 	5 : SmallAreaEmphasis [NUMERICAL]
# 	4 : ZoneVariance [NUMERICAL]
# 	2 : SizeZoneNonUniformity [NUMERICAL]
#
# Attribute in nodes with depth <= 3:
# 	133 : HighGrayLevelZoneEmphasis [NUMERICAL]
# 	99 : LargeAreaHighGrayLevelEmphasis [NUMERICAL]
# 	87 : GrayLevelNonUniformity [NUMERICAL]
# 	83 : SmallAreaLowGrayLevelEmphasis [NUMERICAL]
# 	78 : LargeAreaLowGrayLevelEmphasis [NUMERICAL]
# 	59 : SmallAreaHighGrayLevelEmphasis [NUMERICAL]
# 	38 : LowGrayLevelZoneEmphasis [NUMERICAL]
# 	32 : GrayLevelNonUniformityNormalized [NUMERICAL]
# 	30 : ZoneEntropy [NUMERICAL]
# 	28 : GrayLevelVariance [NUMERICAL]
# 	26 : ZonePercentage [NUMERICAL]
# 	19 : SizeZoneNonUniformityNormalized [NUMERICAL]
# 	18 : ZoneVariance [NUMERICAL]
# 	12 : SmallAreaEmphasis [NUMERICAL]
# 	9 : SizeZoneNonUniformity [NUMERICAL]
# 	7 : LargeAreaEmphasis [NUMERICAL]
#
# Attribute in nodes with depth <= 5:
# 	196 : HighGrayLevelZoneEmphasis [NUMERICAL]
# 	156 : GrayLevelNonUniformity [NUMERICAL]
# 	138 : LargeAreaHighGrayLevelEmphasis [NUMERICAL]
# 	135 : SmallAreaLowGrayLevelEmphasis [NUMERICAL]
# 	123 : LargeAreaLowGrayLevelEmphasis [NUMERICAL]
# 	102 : SmallAreaHighGrayLevelEmphasis [NUMERICAL]
# 	74 : GrayLevelNonUniformityNormalized [NUMERICAL]
# 	72 : LowGrayLevelZoneEmphasis [NUMERICAL]
# 	56 : ZoneEntropy [NUMERICAL]
# 	55 : GrayLevelVariance [NUMERICAL]
# 	39 : ZoneVariance [NUMERICAL]
# 	39 : ZonePercentage [NUMERICAL]
# 	35 : SizeZoneNonUniformityNormalized [NUMERICAL]
# 	26 : SmallAreaEmphasis [NUMERICAL]
# 	21 : SizeZoneNonUniformity [NUMERICAL]
# 	13 : LargeAreaEmphasis [NUMERICAL]
#
# Condition type in nodes:
# 	1280 : HigherCondition
# Condition type in nodes with depth <= 0:
# 	60 : HigherCondition
# Condition type in nodes with depth <= 1:
# 	180 : HigherCondition
# Condition type in nodes with depth <= 2:
# 	403 : HigherCondition
# Condition type in nodes with depth <= 3:
# 	758 : HigherCondition
# Condition type in nodes with depth <= 5:
# 	1280 : HigherCondition
#
# Training logs:
# Number of iteration to final model: 60
# 	Iter:1 train-loss:1.218906 valid-loss:1.258123  train-accuracy:0.958038 valid-accuracy:0.862163
# 	Iter:2 train-loss:1.081503 valid-loss:1.167434  train-accuracy:0.961816 valid-accuracy:0.829188
# 	Iter:3 train-loss:0.964332 valid-loss:1.083001  train-accuracy:0.967956 valid-accuracy:0.849726
# 	Iter:4 train-loss:0.865282 valid-loss:1.004756  train-accuracy:0.970318 valid-accuracy:0.849726
# 	Iter:5 train-loss:0.781131 valid-loss:0.947452  train-accuracy:0.977329 valid-accuracy:0.849726
# 	Iter:6 train-loss:0.709591 valid-loss:0.880909  train-accuracy:0.978274 valid-accuracy:0.849726
# 	Iter:16 train-loss:0.320803 valid-loss:0.597174  train-accuracy:0.982524 valid-accuracy:0.892971
# 	Iter:26 train-loss:0.169381 valid-loss:0.552569  train-accuracy:0.986775 valid-accuracy:0.892971
# 	Iter:36 train-loss:0.110377 valid-loss:0.557708  train-accuracy:0.990554 valid-accuracy:0.898106
# 	Iter:46 train-loss:0.074227 valid-loss:0.567740  train-accuracy:0.996221 valid-accuracy:0.903241
# 	Iter:56 train-loss:0.048823 valid-loss:0.535729  train-accuracy:0.998583 valid-accuracy:0.908375
# 	Iter:66 train-loss:0.033684 valid-loss:0.521605  train-accuracy:1.000000 valid-accuracy:0.913510
# 	Iter:76 train-loss:0.023998 valid-loss:0.530310  train-accuracy:1.000000 valid-accuracy:0.913510
# 	Iter:86 train-loss:0.017896 valid-loss:0.524223  train-accuracy:1.000000 valid-accuracy:0.913510

# %%
# Model features
model.make_inspector().features()
# Out:
# ["GrayLevelNonUniformity" (1; #0),
#  "GrayLevelNonUniformityNormalized" (1; #1),
#  "GrayLevelVariance" (1; #2),
#  "HighGrayLevelZoneEmphasis" (1; #3),
#  "LargeAreaEmphasis" (1; #4),
#  "LargeAreaHighGrayLevelEmphasis" (1; #5),
#  "LargeAreaLowGrayLevelEmphasis" (1; #6),
#  "LowGrayLevelZoneEmphasis" (1; #7),
#  "SizeZoneNonUniformity" (1; #8),
#  "SizeZoneNonUniformityNormalized" (1; #9),
#  "SmallAreaEmphasis" (1; #10),
#  "SmallAreaHighGrayLevelEmphasis" (1; #11),
#  "SmallAreaLowGrayLevelEmphasis" (1; #12),
#  "ZoneEntropy" (1; #13),
#  "ZonePercentage" (1; #14),
#  "ZoneVariance" (1; #15)]

# %%
# Feature importance
model.make_inspector().variable_importances()
# Out:
# {'INV_MEAN_MIN_DEPTH': [("HighGrayLevelZoneEmphasis" (1; #3),
#    0.36351903909525785),
#   ("LargeAreaHighGrayLevelEmphasis" (1; #5), 0.25113115086779564),
#   ("SmallAreaLowGrayLevelEmphasis" (1; #12), 0.2285840319692808),
#   ("GrayLevelNonUniformity" (1; #0), 0.2282147809105503),
#   ("SmallAreaHighGrayLevelEmphasis" (1; #11), 0.20850235815152315),
#   ("LargeAreaLowGrayLevelEmphasis" (1; #6), 0.20712215677802664),
#   ("LowGrayLevelZoneEmphasis" (1; #7), 0.1982441306142012),
#   ("GrayLevelNonUniformityNormalized" (1; #1), 0.18775242563045857),
#   ("ZoneEntropy" (1; #13), 0.18701555260979258),
#   ("GrayLevelVariance" (1; #2), 0.1855423430200786),
#   ("ZonePercentage" (1; #14), 0.18482659371310953),
#   ("SizeZoneNonUniformityNormalized" (1; #9), 0.18255823492389597),
#   ("ZoneVariance" (1; #15), 0.1824533502268762),
#   ("SmallAreaEmphasis" (1; #10), 0.18066007233425038),
#   ("SizeZoneNonUniformity" (1; #8), 0.17822286302668003),
#   ("LargeAreaEmphasis" (1; #4), 0.17794145990571447)],
#  'NUM_AS_ROOT': [("HighGrayLevelZoneEmphasis" (1; #3), 34.0),
#   ("SmallAreaLowGrayLevelEmphasis" (1; #12), 8.0),
#   ("LargeAreaHighGrayLevelEmphasis" (1; #5), 7.0),
#   ("SmallAreaHighGrayLevelEmphasis" (1; #11), 6.0),
#   ("LowGrayLevelZoneEmphasis" (1; #7), 3.0),
#   ("LargeAreaLowGrayLevelEmphasis" (1; #6), 2.0)],
#  'SUM_SCORE': [("HighGrayLevelZoneEmphasis" (1; #3), 931.7949665262854),
#   ("GrayLevelNonUniformity" (1; #0), 283.8808595883331),
#   ("LargeAreaLowGrayLevelEmphasis" (1; #6), 79.91075370061847),
#   ("GrayLevelNonUniformityNormalized" (1; #1), 55.14449519412021),
#   ("LargeAreaHighGrayLevelEmphasis" (1; #5), 45.770163776746),
#   ("LowGrayLevelZoneEmphasis" (1; #7), 43.67163402207112),
#   ("SmallAreaHighGrayLevelEmphasis" (1; #11), 34.26502364060358),
#   ("SmallAreaLowGrayLevelEmphasis" (1; #12), 33.839042596834695),
#   ("SmallAreaEmphasis" (1; #10), 21.181685661754553),
#   ("ZonePercentage" (1; #14), 17.266793540756517),
#   ("SizeZoneNonUniformityNormalized" (1; #9), 16.49266317942855),
#   ("GrayLevelVariance" (1; #2), 12.566291024861243),
#   ("ZoneEntropy" (1; #13), 12.291933870383112),
#   ("ZoneVariance" (1; #15), 11.548310094816395),
#   ("LargeAreaEmphasis" (1; #4), 1.4550114220827255),
#   ("SizeZoneNonUniformity" (1; #8), 1.4131881577261403)],
#  'NUM_NODES': [("HighGrayLevelZoneEmphasis" (1; #3), 196.0),
#   ("GrayLevelNonUniformity" (1; #0), 156.0),
#   ("LargeAreaHighGrayLevelEmphasis" (1; #5), 138.0),
#   ("SmallAreaLowGrayLevelEmphasis" (1; #12), 135.0),
#   ("LargeAreaLowGrayLevelEmphasis" (1; #6), 123.0),
#   ("SmallAreaHighGrayLevelEmphasis" (1; #11), 102.0),
#   ("GrayLevelNonUniformityNormalized" (1; #1), 74.0),
#   ("LowGrayLevelZoneEmphasis" (1; #7), 72.0),
#   ("ZoneEntropy" (1; #13), 56.0),
#   ("GrayLevelVariance" (1; #2), 55.0),
#   ("ZonePercentage" (1; #14), 39.0),
#   ("ZoneVariance" (1; #15), 39.0),
#   ("SizeZoneNonUniformityNormalized" (1; #9), 35.0),
#   ("SmallAreaEmphasis" (1; #10), 26.0),
#   ("SizeZoneNonUniformity" (1; #8), 21.0),
#   ("LargeAreaEmphasis" (1; #4), 13.0)]}

# %%
# Model self evaluation
model.make_inspector().evaluation()
# Out:
# Evaluation(num_examples=None, accuracy=0.9135097861289978, loss=0.5107044577598572, rmse=None, ndcg=None, aucs=None, auuc=None, qini=None)

# %%
logs = model.make_inspector().training_logs()

plt.figure(figsize=(12, 4))
plt.subplot(1, 2, 1)
plt.plot([log.num_trees for log in logs], [log.evaluation.accuracy for log in logs])
plt.xlabel("Number of trees")
plt.ylabel("Accuracy (out-of-bag)")
plt.subplot(1, 2, 2)
plt.plot([log.num_trees for log in logs], [log.evaluation.loss for log in logs])
plt.xlabel("Number of trees")
plt.ylabel("Logloss (out-of-bag)")
plt.show()

# %% [markdown]
# Calculate the score of our hold-out validation dataset

# %%
predictions = model.predict(val_ds)
y_true      = validation_data["label"]

from sklearn.metrics import roc_auc_score
ROC_AUC = roc_auc_score(y_true, predictions)
print("The ROC AUC score is %.5f" % ROC_AUC )
# Out:
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 57ms/step
# The ROC AUC score is 0.94913

# %%
# Compute binary classification metrics with sklearn
import numpy as np
from sklearn.metrics import (
    accuracy_score,
    precision_score,
    recall_score,
    f1_score,
    roc_auc_score,
    average_precision_score,
    confusion_matrix,
    classification_report,
    matthews_corrcoef,
    log_loss,
    brier_score_loss,
)

# Get predictions (probabilities or class labels)
preds = model.predict(test_ds)
# If model outputs probabilities, convert to labels by threshold 0.5
if preds.ndim == 2:
    # For TFDF classification, preds may be class probabilities with shape (N, 2)
    if preds.shape[1] == 2:
        pos_probs = preds[:, 1]
    else:
        # If single-probability column (positive class)
        pos_probs = preds[:, -1]
    y_pred = (pos_probs >= 0.5).astype(int)
else:
    # Already class labels
    y_pred = preds.astype(int)
    pos_probs = None

# Ground truth labels (must be 0/1 integers)
y_true = test_data["label"].astype(int).to_numpy()

# Core metrics
metrics = {}
metrics["accuracy"] = accuracy_score(y_true, y_pred)
metrics["precision"] = precision_score(y_true, y_pred, zero_division=0)
metrics["recall"] = recall_score(y_true, y_pred, zero_division=0)
metrics["f1"] = f1_score(y_true, y_pred, zero_division=0)
metrics["mcc"] = matthews_corrcoef(y_true, y_pred)

# Probabilistic metrics (only if we have probabilities)
if pos_probs is not None:
    metrics["roc_auc"] = roc_auc_score(y_true, pos_probs)
    metrics["pr_auc"] = average_precision_score(y_true, pos_probs)
    metrics["log_loss"] = log_loss(y_true, pos_probs, labels=[0,1])
    metrics["brier_score"] = brier_score_loss(y_true, pos_probs)

# Confusion matrix and detailed report
cm = confusion_matrix(y_true, y_pred, labels=[0,1])
report = classification_report(y_true, y_pred, digits=4)

print("Sklearn binary metrics:")
for k, v in metrics.items():
    print(f"{k}: {v:.4f}")
print("\nConfusion matrix:\n", cm)
print("\nClassification report:\n", report)
# Out:
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 60ms/step
# Sklearn binary metrics:
# accuracy: 0.9476
# precision: 0.7797
# recall: 0.8679
# f1: 0.8214
# mcc: 0.7924
# roc_auc: 0.9876
# pr_auc: 0.9499
# log_loss: 0.1140
# brier_score: 0.0341
#
# Confusion matrix:
#  [[316  13]
#  [  7  46]]
#
# Classification report:
#                precision    recall  f1-score   support
#
#            0     0.9783    0.9605    0.9693       329
#            1     0.7797    0.8679    0.8214        53
#
#     accuracy                         0.9476       382
#    macro avg     0.8790    0.9142    0.8954       382
# weighted avg     0.9508    0.9476    0.9488       382
