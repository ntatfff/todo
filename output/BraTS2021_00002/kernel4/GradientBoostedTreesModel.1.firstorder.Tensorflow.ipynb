# %%
# Import packages and modules
import numpy  as np
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow_decision_forests as tfdf

from sklearn.model_selection import train_test_split
# Out:
# 2026-08-12 05:35:01.980174: I tensorflow/core/util/port.cc:113] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2026-08-12 05:35:07.958132: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2026-08-12 05:35:23.823576: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
# Check the version of TensorFlow Decision Forests
print("Found TensorFlow Decision Forests v" + tfdf.__version__)
# Out:
# Found TensorFlow Decision Forests v1.9.1

# %%
datasetPath = 'dataset/firstorder/kernel5-radius5/dataset.csv'

# %%
# Parameters
datasetPath = "dataset/firstorder/kernel4/1.dataset.csv"

# %%
# train/validation/test = 70/10/20
dataset = pd.read_csv(datasetPath)

train_data, temp_data = train_test_split(dataset, test_size=0.3, random_state=42)
validation_data, test_data = train_test_split(temp_data, test_size=2/3, random_state=42)

# %%
from sklearn.utils.class_weight import compute_class_weight

# tinh class weight tren tap train
classes = np.array([0, 1])
weights = compute_class_weight(class_weight="balanced", classes=classes, y=train_data["label"])
class_weight = {0: weights[0], 1: weights[1]}

# gan sample_weight cho tung dong
train_data["sample_weight"] = train_data["label"].map(class_weight)
validation_data["sample_weight"] = validation_data["label"].map(class_weight)
test_data["sample_weight"] = test_data["label"].map(class_weight)

# Convert the dataset into a TensorFlow dataset.
train_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    train_data, label="label", weight="sample_weight"
)         
val_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    validation_data, label="label", weight="sample_weight"
)
test_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    test_data, label="label", weight="sample_weight"
)
# Out:
# 2026-08-12 05:36:01.378067: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:984] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2026-08-12 05:36:01.380001: W tensorflow/core/common_runtime/gpu/gpu_device.cc:2251] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...

# %%
import keras

# %%
# %%time

# Train a Gradient Boosted Trees model.
model = tfdf.keras.GradientBoostedTreesModel()

# Add evaluation metrics
model.compile(
    metrics=["accuracy"]
)
model.fit(x=train_ds)

# # Train a Gradient Boosted Trees model.
# model = tfdf.keras.GradientBoostedTreesModel(num_trees=1500)
# model.fit(train_ds)
# Out:
# Use /tmp/tmpyy_l00bw as temporary training directory
# Reading training dataset...
# [WARNING 26-08-12 05:36:01.8310 UTC gradient_boosted_trees.cc:1840] "goss_alpha" set but "sampling_method" not equal to "GOSS".
# [WARNING 26-08-12 05:36:01.8346 UTC gradient_boosted_trees.cc:1851] "goss_beta" set but "sampling_method" not equal to "GOSS".
# [WARNING 26-08-12 05:36:01.8346 UTC gradient_boosted_trees.cc:1865] "selective_gradient_boosting_ratio" set but "sampling_method" not equal to "SELGB".
# Training dataset read in 0:00:03.046850. Found 1336 examples.
# Training model...
# Model trained in 0:00:00.482182
# Compiling model...
# [INFO 26-08-12 05:36:05.5044 UTC kernel.cc:1233] Loading model from path /tmp/tmpyy_l00bw/model/ with prefix 1b5d2513a9ff46da
# [INFO 26-08-12 05:36:05.5069 UTC quick_scorer_extended.cc:911] The binary was compiled without AVX2 support, but your CPU supports it. Enable it for faster model inference.
# [INFO 26-08-12 05:36:05.5070 UTC abstract_model.cc:1362] Engine "GradientBoostedTreesQuickScorerExtended" built
# [INFO 26-08-12 05:36:05.5070 UTC kernel.cc:1061] Use fast generic engine
# Model compiled.
# CPU times: user 5.69 s, sys: 427 ms, total: 6.12 s
# Wall time: 7.02 s

# %%
# Evaluate the model
evaluate = model.evaluate(val_ds, return_dict=True)
print()

for name, value in evaluate.items():
    print(f"{name}: {value:.4f}")
# Out:
# WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 1/1 [==============================] - ETA: 0s - loss: 0.0000e+00 - accuracy: 0.9529
# 1/1 [==============================] - 3s 3s/step - loss: 0.0000e+00 - accuracy: 0.9529
# loss: 0.0000
# accuracy: 0.9529

# %%
# Model Summary
model.summary()
# Out:
# Model: "gradient_boosted_trees_model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
# =================================================================
# Total params: 1 (1.00 Byte)
# Trainable params: 0 (0.00 Byte)
# Non-trainable params: 1 (1.00 Byte)
# _________________________________________________________________
# Type: "GRADIENT_BOOSTED_TREES"
# Task: CLASSIFICATION
# Label: "__LABEL"
#
# Input Features (18):
# 	10Percentile
# 	90Percentile
# 	Energy
# 	Entropy
# 	InterquartileRange
# 	Kurtosis
# 	Maximum
# 	Mean
# 	MeanAbsoluteDeviation
# 	Median
# 	Minimum
# 	Range
# 	RobustMeanAbsoluteDeviation
# 	RootMeanSquared
# 	Skewness
# 	TotalEnergy
# 	Uniformity
# 	Variance
#
# Trained with weights
#
# Variable Importance: INV_MEAN_MIN_DEPTH:
#     1.                      "Median"  0.375844 ################
#     2.                        "Mean"  0.309413 ##########
#     3.                 "TotalEnergy"  0.208971 ##
#     4.                "10Percentile"  0.208961 ##
#     5.                     "Minimum"  0.202783 ##
#     6.                      "Energy"  0.202210 ##
#     7.                     "Maximum"  0.194802 #
#     8.             "RootMeanSquared"  0.194586 #
#     9.                  "Uniformity"  0.185600
#    10.                    "Skewness"  0.185119
#    11.                    "Kurtosis"  0.182057
#    12. "RobustMeanAbsoluteDeviation"  0.180773
#    13.                       "Range"  0.179406
#    14.                    "Variance"  0.178822
#    15.                "90Percentile"  0.178314
#    16.                     "Entropy"  0.178184
#    17.          "InterquartileRange"  0.177822
#    18.       "MeanAbsoluteDeviation"  0.174577
#
# Variable Importance: NUM_AS_ROOT:
#     1.      "Median" 12.000000 ################
#     2.        "Mean" 10.000000 #############
#     3. "TotalEnergy"  3.000000 ##
#     4.      "Energy"  1.000000
#
# Variable Importance: NUM_NODES:
#     1.                      "Median" 107.000000 ################
#     2.                        "Mean" 65.000000 #########
#     3.                     "Maximum" 59.000000 ########
#     4.                    "Skewness" 48.000000 ######
#     5.                "10Percentile" 40.000000 #####
#     6.                 "TotalEnergy" 36.000000 ####
#     7.             "RootMeanSquared" 32.000000 ####
#     8.                    "Kurtosis" 30.000000 ####
#     9.                     "Minimum" 30.000000 ####
#    10.                      "Energy" 28.000000 ###
#    11.                  "Uniformity" 27.000000 ###
#    12.                "90Percentile" 21.000000 ##
#    13.          "InterquartileRange" 21.000000 ##
#    14. "RobustMeanAbsoluteDeviation" 21.000000 ##
#    15.                       "Range" 19.000000 ##
#    16.                     "Entropy" 16.000000 #
#    17.                    "Variance" 15.000000 #
#    18.       "MeanAbsoluteDeviation"  4.000000
#
# Variable Importance: SUM_SCORE:
#     1.                      "Median" 659.044880 ################
#     2.                        "Mean" 497.064780 ############
#     3.                     "Maximum" 62.640803 #
#     4.                      "Energy" 50.226188 #
#     5.                "10Percentile" 46.140133 #
#     6.                 "TotalEnergy" 42.961921 #
#     7.                    "Kurtosis" 32.127266
#     8.                    "Skewness" 27.267090
#     9.          "InterquartileRange" 25.347887
#    10.             "RootMeanSquared" 24.954640
#    11.                  "Uniformity" 22.985820
#    12. "RobustMeanAbsoluteDeviation" 16.354940
#    13.                    "Variance" 13.911416
#    14.                     "Minimum" 13.609083
#    15.                     "Entropy"  9.094505
#    16.                "90Percentile"  9.044035
#    17.                       "Range"  8.863216
#    18.       "MeanAbsoluteDeviation"  1.633254
#
#
#
# Loss: BINOMIAL_LOG_LIKELIHOOD
# Validation loss value: 0.353787
# Number of trees per iteration: 1
# Node format: NOT_SET
# Number of trees: 26
# Total number of nodes: 1264
#
# Number of nodes by tree:
# Count: 26 Average: 48.6154 StdDev: 5.34989
# Min: 35 Max: 55 Ignored: 0
# ----------------------------------------------
# [ 35, 36) 1   3.85%   3.85% ##
# [ 36, 37) 0   0.00%   3.85%
# [ 37, 38) 0   0.00%   3.85%
# [ 38, 39) 0   0.00%   3.85%
# [ 39, 40) 2   7.69%  11.54% ###
# [ 40, 41) 0   0.00%  11.54%
# [ 41, 42) 0   0.00%  11.54%
# [ 42, 43) 0   0.00%  11.54%
# [ 43, 44) 3  11.54%  23.08% #####
# [ 44, 45) 0   0.00%  23.08%
# [ 45, 46) 2   7.69%  30.77% ###
# [ 46, 47) 0   0.00%  30.77%
# [ 47, 48) 0   0.00%  30.77%
# [ 48, 49) 0   0.00%  30.77%
# [ 49, 50) 4  15.38%  46.15% #######
# [ 50, 51) 0   0.00%  46.15%
# [ 51, 52) 6  23.08%  69.23% ##########
# [ 52, 53) 0   0.00%  69.23%
# [ 53, 54) 5  19.23%  88.46% ########
# [ 54, 55] 3  11.54% 100.00% #####
#
# Depth by leafs:
# Count: 645 Average: 4.75194 StdDev: 0.519854
# Min: 3 Max: 5 Ignored: 0
# ----------------------------------------------
# [ 3, 4)  27   4.19%   4.19% #
# [ 4, 5) 106  16.43%  20.62% ##
# [ 5, 5] 512  79.38% 100.00% ##########
#
# Number of training obs by leaf:
# Count: 645 Average: 49.5008 StdDev: 137.124
# Min: 5 Max: 781 Ignored: 0
# ----------------------------------------------
# [   5,  43) 529  82.02%  82.02% ##########
# [  43,  82)  52   8.06%  90.08% #
# [  82, 121)  29   4.50%  94.57% #
# [ 121, 160)   6   0.93%  95.50%
# [ 160, 199)   3   0.47%  95.97%
# [ 199, 238)   0   0.00%  95.97%
# [ 238, 276)   0   0.00%  95.97%
# [ 276, 315)   0   0.00%  95.97%
# [ 315, 354)   0   0.00%  95.97%
# [ 354, 393)   0   0.00%  95.97%
# [ 393, 432)   0   0.00%  95.97%
# [ 432, 471)   0   0.00%  95.97%
# [ 471, 510)   0   0.00%  95.97%
# [ 510, 548)   0   0.00%  95.97%
# [ 548, 587)   0   0.00%  95.97%
# [ 587, 626)   0   0.00%  95.97%
# [ 626, 665)   4   0.62%  96.59%
# [ 665, 704)  13   2.02%  98.60%
# [ 704, 743)   4   0.62%  99.22%
# [ 743, 781]   5   0.78% 100.00%
#
# Attribute in nodes:
# 	107 : Median [NUMERICAL]
# 	65 : Mean [NUMERICAL]
# 	59 : Maximum [NUMERICAL]
# 	48 : Skewness [NUMERICAL]
# 	40 : 10Percentile [NUMERICAL]
# 	36 : TotalEnergy [NUMERICAL]
# 	32 : RootMeanSquared [NUMERICAL]
# 	30 : Minimum [NUMERICAL]
# 	30 : Kurtosis [NUMERICAL]
# 	28 : Energy [NUMERICAL]
# 	27 : Uniformity [NUMERICAL]
# 	21 : RobustMeanAbsoluteDeviation [NUMERICAL]
# 	21 : InterquartileRange [NUMERICAL]
# 	21 : 90Percentile [NUMERICAL]
# 	19 : Range [NUMERICAL]
# 	16 : Entropy [NUMERICAL]
# 	15 : Variance [NUMERICAL]
# 	4 : MeanAbsoluteDeviation [NUMERICAL]
#
# Attribute in nodes with depth <= 0:
# 	12 : Median [NUMERICAL]
# 	10 : Mean [NUMERICAL]
# 	3 : TotalEnergy [NUMERICAL]
# 	1 : Energy [NUMERICAL]
#
# Attribute in nodes with depth <= 1:
# 	23 : Median [NUMERICAL]
# 	17 : Mean [NUMERICAL]
# 	9 : Minimum [NUMERICAL]
# 	9 : 10Percentile [NUMERICAL]
# 	8 : Energy [NUMERICAL]
# 	6 : TotalEnergy [NUMERICAL]
# 	4 : RootMeanSquared [NUMERICAL]
# 	2 : Maximum [NUMERICAL]
#
# Attribute in nodes with depth <= 2:
# 	36 : Median [NUMERICAL]
# 	28 : Mean [NUMERICAL]
# 	19 : 10Percentile [NUMERICAL]
# 	16 : Minimum [NUMERICAL]
# 	15 : RootMeanSquared [NUMERICAL]
# 	15 : Maximum [NUMERICAL]
# 	12 : TotalEnergy [NUMERICAL]
# 	8 : Uniformity [NUMERICAL]
# 	8 : Energy [NUMERICAL]
# 	6 : Skewness [NUMERICAL]
# 	4 : Range [NUMERICAL]
# 	4 : Kurtosis [NUMERICAL]
# 	3 : RobustMeanAbsoluteDeviation [NUMERICAL]
# 	3 : Entropy [NUMERICAL]
# 	2 : Variance [NUMERICAL]
# 	2 : 90Percentile [NUMERICAL]
# 	1 : InterquartileRange [NUMERICAL]
#
# Attribute in nodes with depth <= 3:
# 	68 : Median [NUMERICAL]
# 	43 : Mean [NUMERICAL]
# 	37 : Maximum [NUMERICAL]
# 	29 : 10Percentile [NUMERICAL]
# 	24 : Minimum [NUMERICAL]
# 	21 : Skewness [NUMERICAL]
# 	20 : TotalEnergy [NUMERICAL]
# 	20 : RootMeanSquared [NUMERICAL]
# 	19 : Energy [NUMERICAL]
# 	16 : Uniformity [NUMERICAL]
# 	16 : Kurtosis [NUMERICAL]
# 	10 : Range [NUMERICAL]
# 	9 : RobustMeanAbsoluteDeviation [NUMERICAL]
# 	8 : Entropy [NUMERICAL]
# 	8 : 90Percentile [NUMERICAL]
# 	7 : Variance [NUMERICAL]
# 	7 : InterquartileRange [NUMERICAL]
# 	1 : MeanAbsoluteDeviation [NUMERICAL]
#
# Attribute in nodes with depth <= 5:
# 	107 : Median [NUMERICAL]
# 	65 : Mean [NUMERICAL]
# 	59 : Maximum [NUMERICAL]
# 	48 : Skewness [NUMERICAL]
# 	40 : 10Percentile [NUMERICAL]
# 	36 : TotalEnergy [NUMERICAL]
# 	32 : RootMeanSquared [NUMERICAL]
# 	30 : Minimum [NUMERICAL]
# 	30 : Kurtosis [NUMERICAL]
# 	28 : Energy [NUMERICAL]
# 	27 : Uniformity [NUMERICAL]
# 	21 : RobustMeanAbsoluteDeviation [NUMERICAL]
# 	21 : InterquartileRange [NUMERICAL]
# 	21 : 90Percentile [NUMERICAL]
# 	19 : Range [NUMERICAL]
# 	16 : Entropy [NUMERICAL]
# 	15 : Variance [NUMERICAL]
# 	4 : MeanAbsoluteDeviation [NUMERICAL]
#
# Condition type in nodes:
# 	619 : HigherCondition
# Condition type in nodes with depth <= 0:
# 	26 : HigherCondition
# Condition type in nodes with depth <= 1:
# 	78 : HigherCondition
# Condition type in nodes with depth <= 2:
# 	182 : HigherCondition
# Condition type in nodes with depth <= 3:
# 	363 : HigherCondition
# Condition type in nodes with depth <= 5:
# 	619 : HigherCondition
#
# Training logs:
# Number of iteration to final model: 26
# 	Iter:1 train-loss:1.219124 valid-loss:1.255393  train-accuracy:0.954314 valid-accuracy:0.837452
# 	Iter:2 train-loss:1.081938 valid-loss:1.149116  train-accuracy:0.961430 valid-accuracy:0.852596
# 	Iter:3 train-loss:0.968546 valid-loss:1.047770  train-accuracy:0.978652 valid-accuracy:0.894494
# 	Iter:4 train-loss:0.868651 valid-loss:0.961895  train-accuracy:0.976137 valid-accuracy:0.894494
# 	Iter:5 train-loss:0.785229 valid-loss:0.873130  train-accuracy:0.981024 valid-accuracy:0.899542
# 	Iter:6 train-loss:0.711852 valid-loss:0.795845  train-accuracy:0.981973 valid-accuracy:0.931346
# 	Iter:16 train-loss:0.306730 valid-loss:0.466892  train-accuracy:0.989563 valid-accuracy:0.931346
# 	Iter:26 train-loss:0.165982 valid-loss:0.353787  train-accuracy:0.993358 valid-accuracy:0.931346
# 	Iter:36 train-loss:0.109657 valid-loss:0.383689  train-accuracy:0.995256 valid-accuracy:0.931346
# 	Iter:46 train-loss:0.076791 valid-loss:0.380442  train-accuracy:0.997154 valid-accuracy:0.931346
# 	Iter:56 train-loss:0.056433 valid-loss:0.412423  train-accuracy:0.998102 valid-accuracy:0.931346

# %%
# Model features
model.make_inspector().features()
# Out:
# ["10Percentile" (1; #0),
#  "90Percentile" (1; #1),
#  "Energy" (1; #2),
#  "Entropy" (1; #3),
#  "InterquartileRange" (1; #4),
#  "Kurtosis" (1; #5),
#  "Maximum" (1; #6),
#  "Mean" (1; #7),
#  "MeanAbsoluteDeviation" (1; #8),
#  "Median" (1; #9),
#  "Minimum" (1; #10),
#  "Range" (1; #11),
#  "RobustMeanAbsoluteDeviation" (1; #12),
#  "RootMeanSquared" (1; #13),
#  "Skewness" (1; #14),
#  "TotalEnergy" (1; #15),
#  "Uniformity" (1; #16),
#  "Variance" (1; #17)]

# %%
# Feature importance
model.make_inspector().variable_importances()
# Out:
# {'INV_MEAN_MIN_DEPTH': [("Median" (1; #9), 0.3758435449852387),
#   ("Mean" (1; #7), 0.30941250397519776),
#   ("TotalEnergy" (1; #15), 0.20897064778107363),
#   ("10Percentile" (1; #0), 0.20896107001532255),
#   ("Minimum" (1; #10), 0.20278294979482647),
#   ("Energy" (1; #2), 0.20220992373525193),
#   ("Maximum" (1; #6), 0.19480200788794924),
#   ("RootMeanSquared" (1; #13), 0.19458551684706363),
#   ("Uniformity" (1; #16), 0.1855998935114096),
#   ("Skewness" (1; #14), 0.1851191318577675),
#   ("Kurtosis" (1; #5), 0.18205693699855624),
#   ("RobustMeanAbsoluteDeviation" (1; #12), 0.18077300591451986),
#   ("Range" (1; #11), 0.17940641079704478),
#   ("Variance" (1; #17), 0.17882160767316344),
#   ("90Percentile" (1; #1), 0.1783139275725648),
#   ("Entropy" (1; #3), 0.17818449597768105),
#   ("InterquartileRange" (1; #4), 0.17782170257134894),
#   ("MeanAbsoluteDeviation" (1; #8), 0.1745770867393322)],
#  'NUM_AS_ROOT': [("Median" (1; #9), 12.0),
#   ("Mean" (1; #7), 10.0),
#   ("TotalEnergy" (1; #15), 3.0),
#   ("Energy" (1; #2), 1.0)],
#  'SUM_SCORE': [("Median" (1; #9), 659.0448800933963),
#   ("Mean" (1; #7), 497.0647798716509),
#   ("Maximum" (1; #6), 62.64080340505121),
#   ("Energy" (1; #2), 50.226187746366975),
#   ("10Percentile" (1; #0), 46.140132895569074),
#   ("TotalEnergy" (1; #15), 42.96192142305431),
#   ("Kurtosis" (1; #5), 32.1272662139466),
#   ("Skewness" (1; #14), 27.26708979651226),
#   ("InterquartileRange" (1; #4), 25.34788663984309),
#   ("RootMeanSquared" (1; #13), 24.954640396217187),
#   ("Uniformity" (1; #16), 22.98582030740289),
#   ("RobustMeanAbsoluteDeviation" (1; #12), 16.35494033875328),
#   ("Variance" (1; #17), 13.911415528573277),
#   ("Minimum" (1; #10), 13.60908287912653),
#   ("Entropy" (1; #3), 9.094504996416529),
#   ("90Percentile" (1; #1), 9.044034935868034),
#   ("Range" (1; #11), 8.86321619142227),
#   ("MeanAbsoluteDeviation" (1; #8), 1.6332543503103483)],
#  'NUM_NODES': [("Median" (1; #9), 107.0),
#   ("Mean" (1; #7), 65.0),
#   ("Maximum" (1; #6), 59.0),
#   ("Skewness" (1; #14), 48.0),
#   ("10Percentile" (1; #0), 40.0),
#   ("TotalEnergy" (1; #15), 36.0),
#   ("RootMeanSquared" (1; #13), 32.0),
#   ("Kurtosis" (1; #5), 30.0),
#   ("Minimum" (1; #10), 30.0),
#   ("Energy" (1; #2), 28.0),
#   ("Uniformity" (1; #16), 27.0),
#   ("90Percentile" (1; #1), 21.0),
#   ("InterquartileRange" (1; #4), 21.0),
#   ("RobustMeanAbsoluteDeviation" (1; #12), 21.0),
#   ("Range" (1; #11), 19.0),
#   ("Entropy" (1; #3), 16.0),
#   ("Variance" (1; #17), 15.0),
#   ("MeanAbsoluteDeviation" (1; #8), 4.0)]}

# %%
# Model self evaluation
model.make_inspector().evaluation()
# Out:
# Evaluation(num_examples=None, accuracy=0.931345522403717, loss=0.3537870943546295, rmse=None, ndcg=None, aucs=None, auuc=None, qini=None)

# %%
logs = model.make_inspector().training_logs()

plt.figure(figsize=(12, 4))
plt.subplot(1, 2, 1)
plt.plot([log.num_trees for log in logs], [log.evaluation.accuracy for log in logs])
plt.xlabel("Number of trees")
plt.ylabel("Accuracy (out-of-bag)")
plt.subplot(1, 2, 2)
plt.plot([log.num_trees for log in logs], [log.evaluation.loss for log in logs])
plt.xlabel("Number of trees")
plt.ylabel("Logloss (out-of-bag)")
plt.show()

# %% [markdown]
# Calculate the score of our hold-out validation dataset

# %%
predictions = model.predict(val_ds)
y_true      = validation_data["label"]

from sklearn.metrics import roc_auc_score
ROC_AUC = roc_auc_score(y_true, predictions)
print("The ROC AUC score is %.5f" % ROC_AUC )
# Out:
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 54ms/step
# The ROC AUC score is 0.95322

# %%
# Compute binary classification metrics with sklearn
import numpy as np
from sklearn.metrics import (
    accuracy_score,
    precision_score,
    recall_score,
    f1_score,
    roc_auc_score,
    average_precision_score,
    confusion_matrix,
    classification_report,
    matthews_corrcoef,
    log_loss,
    brier_score_loss,
)

# Get predictions (probabilities or class labels)
preds = model.predict(test_ds)
# If model outputs probabilities, convert to labels by threshold 0.5
if preds.ndim == 2:
    # For TFDF classification, preds may be class probabilities with shape (N, 2)
    if preds.shape[1] == 2:
        pos_probs = preds[:, 1]
    else:
        # If single-probability column (positive class)
        pos_probs = preds[:, -1]
    y_pred = (pos_probs >= 0.5).astype(int)
else:
    # Already class labels
    y_pred = preds.astype(int)
    pos_probs = None

# Ground truth labels (must be 0/1 integers)
y_true = test_data["label"].astype(int).to_numpy()

# Core metrics
metrics = {}
metrics["accuracy"] = accuracy_score(y_true, y_pred)
metrics["precision"] = precision_score(y_true, y_pred, zero_division=0)
metrics["recall"] = recall_score(y_true, y_pred, zero_division=0)
metrics["f1"] = f1_score(y_true, y_pred, zero_division=0)
metrics["mcc"] = matthews_corrcoef(y_true, y_pred)

# Probabilistic metrics (only if we have probabilities)
if pos_probs is not None:
    metrics["roc_auc"] = roc_auc_score(y_true, pos_probs)
    metrics["pr_auc"] = average_precision_score(y_true, pos_probs)
    metrics["log_loss"] = log_loss(y_true, pos_probs, labels=[0,1])
    metrics["brier_score"] = brier_score_loss(y_true, pos_probs)

# Confusion matrix and detailed report
cm = confusion_matrix(y_true, y_pred, labels=[0,1])
report = classification_report(y_true, y_pred, digits=4)

print("Sklearn binary metrics:")
for k, v in metrics.items():
    print(f"{k}: {v:.4f}")
print("\nConfusion matrix:\n", cm)
print("\nClassification report:\n", report)
# Out:
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 61ms/step
# Sklearn binary metrics:
# accuracy: 0.9319
# precision: 0.7895
# recall: 0.7627
# f1: 0.7759
# mcc: 0.7359
# roc_auc: 0.9697
# pr_auc: 0.8963
# log_loss: 0.1712
# brier_score: 0.0469
#
# Confusion matrix:
#  [[311  12]
#  [ 14  45]]
#
# Classification report:
#                precision    recall  f1-score   support
#
#            0     0.9569    0.9628    0.9599       323
#            1     0.7895    0.7627    0.7759        59
#
#     accuracy                         0.9319       382
#    macro avg     0.8732    0.8628    0.8679       382
# weighted avg     0.9311    0.9319    0.9315       382
