# %%
# Import packages and modules
import numpy  as np
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow_decision_forests as tfdf

from sklearn.model_selection import train_test_split
# Out:
# 2026-08-12 05:37:30.675304: I tensorflow/core/util/port.cc:113] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2026-08-12 05:37:31.042369: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2026-08-12 05:37:35.349928: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
# Check the version of TensorFlow Decision Forests
print("Found TensorFlow Decision Forests v" + tfdf.__version__)
# Out:
# Found TensorFlow Decision Forests v1.9.1

# %%
datasetPath = 'dataset/firstorder/kernel5-radius5/dataset.csv'

# %%
# Parameters
datasetPath = "dataset/glrlm/kernel4/1.dataset.csv"

# %%
# train/validation/test = 70/10/20
dataset = pd.read_csv(datasetPath)

train_data, temp_data = train_test_split(dataset, test_size=0.3, random_state=42)
validation_data, test_data = train_test_split(temp_data, test_size=2/3, random_state=42)

# %%
from sklearn.utils.class_weight import compute_class_weight

# tinh class weight tren tap train
classes = np.array([0, 1])
weights = compute_class_weight(class_weight="balanced", classes=classes, y=train_data["label"])
class_weight = {0: weights[0], 1: weights[1]}

# gan sample_weight cho tung dong
train_data["sample_weight"] = train_data["label"].map(class_weight)
validation_data["sample_weight"] = validation_data["label"].map(class_weight)
test_data["sample_weight"] = test_data["label"].map(class_weight)

# Convert the dataset into a TensorFlow dataset.
train_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    train_data, label="label", weight="sample_weight"
)         
val_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    validation_data, label="label", weight="sample_weight"
)
test_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    test_data, label="label", weight="sample_weight"
)
# Out:
# 2026-08-12 05:37:50.037466: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:984] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2026-08-12 05:37:50.038878: W tensorflow/core/common_runtime/gpu/gpu_device.cc:2251] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...

# %%
import keras

# %%
# %%time

# Train a Gradient Boosted Trees model.
model = tfdf.keras.GradientBoostedTreesModel()

# Add evaluation metrics
model.compile(
    metrics=["accuracy"]
)
model.fit(x=train_ds)

# # Train a Gradient Boosted Trees model.
# model = tfdf.keras.GradientBoostedTreesModel(num_trees=1500)
# model.fit(train_ds)
# Out:
# Use /tmp/tmph7htzm6e as temporary training directory
# Reading training dataset...
# [WARNING 26-08-12 05:37:50.1774 UTC gradient_boosted_trees.cc:1840] "goss_alpha" set but "sampling_method" not equal to "GOSS".
# [WARNING 26-08-12 05:37:50.1777 UTC gradient_boosted_trees.cc:1851] "goss_beta" set but "sampling_method" not equal to "GOSS".
# [WARNING 26-08-12 05:37:50.1777 UTC gradient_boosted_trees.cc:1865] "selective_gradient_boosting_ratio" set but "sampling_method" not equal to "SELGB".
# Training dataset read in 0:00:02.381330. Found 1336 examples.
# Training model...
# Model trained in 0:00:00.243504
# Compiling model...
# [INFO 26-08-12 05:37:52.8299 UTC kernel.cc:1233] Loading model from path /tmp/tmph7htzm6e/model/ with prefix 767c5c6d2a294690
# [INFO 26-08-12 05:37:52.8320 UTC quick_scorer_extended.cc:911] The binary was compiled without AVX2 support, but your CPU supports it. Enable it for faster model inference.
# [INFO 26-08-12 05:37:52.8322 UTC abstract_model.cc:1362] Engine "GradientBoostedTreesQuickScorerExtended" built
# [INFO 26-08-12 05:37:52.8322 UTC kernel.cc:1061] Use fast generic engine
# Model compiled.
# CPU times: user 5.54 s, sys: 409 ms, total: 5.95 s
# Wall time: 5.53 s

# %%
# Evaluate the model
evaluate = model.evaluate(val_ds, return_dict=True)
print()

for name, value in evaluate.items():
    print(f"{name}: {value:.4f}")
# Out:
# WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 1/1 [==============================] - ETA: 0s - loss: 0.0000e+00 - accuracy: 0.9581
# 1/1 [==============================] - 3s 3s/step - loss: 0.0000e+00 - accuracy: 0.9581
# loss: 0.0000
# accuracy: 0.9581

# %%
# Model Summary
model.summary()
# Out:
# Model: "gradient_boosted_trees_model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
# =================================================================
# Total params: 1 (1.00 Byte)
# Trainable params: 0 (0.00 Byte)
# Non-trainable params: 1 (1.00 Byte)
# _________________________________________________________________
# Type: "GRADIENT_BOOSTED_TREES"
# Task: CLASSIFICATION
# Label: "__LABEL"
#
# Input Features (16):
# 	GrayLevelNonUniformity
# 	GrayLevelNonUniformityNormalized
# 	GrayLevelVariance
# 	HighGrayLevelRunEmphasis
# 	LongRunEmphasis
# 	LongRunHighGrayLevelEmphasis
# 	LongRunLowGrayLevelEmphasis
# 	LowGrayLevelRunEmphasis
# 	RunEntropy
# 	RunLengthNonUniformity
# 	RunLengthNonUniformityNormalized
# 	RunPercentage
# 	RunVariance
# 	ShortRunEmphasis
# 	ShortRunHighGrayLevelEmphasis
# 	ShortRunLowGrayLevelEmphasis
#
# Trained with weights
#
# Variable Importance: INV_MEAN_MIN_DEPTH:
#     1.     "LongRunHighGrayLevelEmphasis"  1.000000 ################
#     2.                       "RunEntropy"  0.220014
#     3.    "ShortRunHighGrayLevelEmphasis"  0.218188
#     4.         "HighGrayLevelRunEmphasis"  0.207677
#     5.                "GrayLevelVariance"  0.190478
#     6.      "LongRunLowGrayLevelEmphasis"  0.185945
#     7.           "GrayLevelNonUniformity"  0.182386
#     8.          "LowGrayLevelRunEmphasis"  0.179713
#     9.           "RunLengthNonUniformity"  0.179389
#    10. "RunLengthNonUniformityNormalized"  0.178550
#    11.     "ShortRunLowGrayLevelEmphasis"  0.178315
#    12.                    "RunPercentage"  0.178109
#    13.                 "ShortRunEmphasis"  0.177774
#    14. "GrayLevelNonUniformityNormalized"  0.177218
#    15.                      "RunVariance"  0.176364
#    16.                  "LongRunEmphasis"  0.175698
#
# Variable Importance: NUM_AS_ROOT:
#     1. "LongRunHighGrayLevelEmphasis" 27.000000
#
# Variable Importance: NUM_NODES:
#     1.     "LongRunHighGrayLevelEmphasis" 170.000000 ################
#     2.                       "RunEntropy" 79.000000 #######
#     3.    "ShortRunHighGrayLevelEmphasis" 73.000000 ######
#     4.                "GrayLevelVariance" 56.000000 #####
#     5.         "HighGrayLevelRunEmphasis" 47.000000 ####
#     6.      "LongRunLowGrayLevelEmphasis" 39.000000 ###
#     7.           "GrayLevelNonUniformity" 24.000000 #
#     8.          "LowGrayLevelRunEmphasis" 24.000000 #
#     9.     "ShortRunLowGrayLevelEmphasis" 18.000000 #
#    10. "GrayLevelNonUniformityNormalized" 14.000000
#    11.           "RunLengthNonUniformity" 12.000000
#    12.                 "ShortRunEmphasis" 12.000000
#    13. "RunLengthNonUniformityNormalized" 11.000000
#    14.                      "RunVariance"  7.000000
#    15.                    "RunPercentage"  6.000000
#    16.                  "LongRunEmphasis"  4.000000
#
# Variable Importance: SUM_SCORE:
#     1.     "LongRunHighGrayLevelEmphasis" 1261.695381 ################
#     2.    "ShortRunHighGrayLevelEmphasis" 78.301224
#     3.                       "RunEntropy" 73.238819
#     4.                "GrayLevelVariance" 31.654701
#     5.         "HighGrayLevelRunEmphasis" 26.109164
#     6.           "GrayLevelNonUniformity" 16.046542
#     7.      "LongRunLowGrayLevelEmphasis" 14.571730
#     8.          "LowGrayLevelRunEmphasis" 11.160297
#     9.           "RunLengthNonUniformity"  8.790969
#    10.                      "RunVariance"  8.434711
#    11.     "ShortRunLowGrayLevelEmphasis"  8.116646
#    12.                 "ShortRunEmphasis"  7.247278
#    13.                    "RunPercentage"  3.542311
#    14.                  "LongRunEmphasis"  3.428073
#    15. "RunLengthNonUniformityNormalized"  3.044567
#    16. "GrayLevelNonUniformityNormalized"  1.956189
#
#
#
# Loss: BINOMIAL_LOG_LIKELIHOOD
# Validation loss value: 0.349662
# Number of trees per iteration: 1
# Node format: NOT_SET
# Number of trees: 27
# Total number of nodes: 1219
#
# Number of nodes by tree:
# Count: 27 Average: 45.1481 StdDev: 6.13251
# Min: 35 Max: 55 Ignored: 0
# ----------------------------------------------
# [ 35, 36) 2   7.41%   7.41% #####
# [ 36, 37) 0   0.00%   7.41%
# [ 37, 38) 2   7.41%  14.81% #####
# [ 38, 39) 0   0.00%  14.81%
# [ 39, 40) 3  11.11%  25.93% ########
# [ 40, 41) 0   0.00%  25.93%
# [ 41, 42) 2   7.41%  33.33% #####
# [ 42, 43) 0   0.00%  33.33%
# [ 43, 44) 4  14.81%  48.15% ##########
# [ 44, 45) 0   0.00%  48.15%
# [ 45, 46) 2   7.41%  55.56% #####
# [ 46, 47) 0   0.00%  55.56%
# [ 47, 48) 1   3.70%  59.26% ###
# [ 48, 49) 0   0.00%  59.26%
# [ 49, 50) 4  14.81%  74.07% ##########
# [ 50, 51) 0   0.00%  74.07%
# [ 51, 52) 2   7.41%  81.48% #####
# [ 52, 53) 0   0.00%  81.48%
# [ 53, 54) 3  11.11%  92.59% ########
# [ 54, 55] 2   7.41% 100.00% #####
#
# Depth by leafs:
# Count: 623 Average: 4.72713 StdDev: 0.630437
# Min: 2 Max: 5 Ignored: 0
# ----------------------------------------------
# [ 2, 3)   9   1.44%   1.44%
# [ 3, 4)  35   5.62%   7.06% #
# [ 4, 5)  73  11.72%  18.78% #
# [ 5, 5] 506  81.22% 100.00% ##########
#
# Number of training obs by leaf:
# Count: 623 Average: 53.2199 StdDev: 123.863
# Min: 5 Max: 787 Ignored: 0
# ----------------------------------------------
# [   5,  44) 479  76.89%  76.89% ##########
# [  44,  83)  58   9.31%  86.20% #
# [  83, 122)  36   5.78%  91.97% #
# [ 122, 161)  11   1.77%  93.74%
# [ 161, 200)   2   0.32%  94.06%
# [ 200, 239)   7   1.12%  95.18%
# [ 239, 279)   0   0.00%  95.18%
# [ 279, 318)   1   0.16%  95.35%
# [ 318, 357)   1   0.16%  95.51%
# [ 357, 396)   1   0.16%  95.67%
# [ 396, 435)   0   0.00%  95.67%
# [ 435, 474)   1   0.16%  95.83%
# [ 474, 513)  12   1.93%  97.75%
# [ 513, 553)   1   0.16%  97.91%
# [ 553, 592)   1   0.16%  98.07%
# [ 592, 631)   0   0.00%  98.07%
# [ 631, 670)   3   0.48%  98.56%
# [ 670, 709)   4   0.64%  99.20%
# [ 709, 748)   3   0.48%  99.68%
# [ 748, 787]   2   0.32% 100.00%
#
# Attribute in nodes:
# 	170 : LongRunHighGrayLevelEmphasis [NUMERICAL]
# 	79 : RunEntropy [NUMERICAL]
# 	73 : ShortRunHighGrayLevelEmphasis [NUMERICAL]
# 	56 : GrayLevelVariance [NUMERICAL]
# 	47 : HighGrayLevelRunEmphasis [NUMERICAL]
# 	39 : LongRunLowGrayLevelEmphasis [NUMERICAL]
# 	24 : LowGrayLevelRunEmphasis [NUMERICAL]
# 	24 : GrayLevelNonUniformity [NUMERICAL]
# 	18 : ShortRunLowGrayLevelEmphasis [NUMERICAL]
# 	14 : GrayLevelNonUniformityNormalized [NUMERICAL]
# 	12 : ShortRunEmphasis [NUMERICAL]
# 	12 : RunLengthNonUniformity [NUMERICAL]
# 	11 : RunLengthNonUniformityNormalized [NUMERICAL]
# 	7 : RunVariance [NUMERICAL]
# 	6 : RunPercentage [NUMERICAL]
# 	4 : LongRunEmphasis [NUMERICAL]
#
# Attribute in nodes with depth <= 0:
# 	27 : LongRunHighGrayLevelEmphasis [NUMERICAL]
#
# Attribute in nodes with depth <= 1:
# 	62 : LongRunHighGrayLevelEmphasis [NUMERICAL]
# 	7 : RunEntropy [NUMERICAL]
# 	7 : HighGrayLevelRunEmphasis [NUMERICAL]
# 	4 : ShortRunHighGrayLevelEmphasis [NUMERICAL]
# 	1 : GrayLevelNonUniformity [NUMERICAL]
#
# Attribute in nodes with depth <= 2:
# 	80 : LongRunHighGrayLevelEmphasis [NUMERICAL]
# 	31 : RunEntropy [NUMERICAL]
# 	25 : ShortRunHighGrayLevelEmphasis [NUMERICAL]
# 	15 : HighGrayLevelRunEmphasis [NUMERICAL]
# 	8 : GrayLevelVariance [NUMERICAL]
# 	6 : LongRunLowGrayLevelEmphasis [NUMERICAL]
# 	4 : GrayLevelNonUniformity [NUMERICAL]
# 	3 : RunLengthNonUniformity [NUMERICAL]
# 	2 : ShortRunEmphasis [NUMERICAL]
# 	2 : RunPercentage [NUMERICAL]
# 	2 : RunLengthNonUniformityNormalized [NUMERICAL]
# 	1 : ShortRunLowGrayLevelEmphasis [NUMERICAL]
# 	1 : LowGrayLevelRunEmphasis [NUMERICAL]
#
# Attribute in nodes with depth <= 3:
# 	113 : LongRunHighGrayLevelEmphasis [NUMERICAL]
# 	49 : ShortRunHighGrayLevelEmphasis [NUMERICAL]
# 	43 : RunEntropy [NUMERICAL]
# 	31 : HighGrayLevelRunEmphasis [NUMERICAL]
# 	26 : GrayLevelVariance [NUMERICAL]
# 	18 : LongRunLowGrayLevelEmphasis [NUMERICAL]
# 	14 : GrayLevelNonUniformity [NUMERICAL]
# 	9 : RunLengthNonUniformity [NUMERICAL]
# 	7 : ShortRunLowGrayLevelEmphasis [NUMERICAL]
# 	7 : LowGrayLevelRunEmphasis [NUMERICAL]
# 	6 : ShortRunEmphasis [NUMERICAL]
# 	6 : RunLengthNonUniformityNormalized [NUMERICAL]
# 	5 : GrayLevelNonUniformityNormalized [NUMERICAL]
# 	4 : RunPercentage [NUMERICAL]
# 	3 : RunVariance [NUMERICAL]
# 	2 : LongRunEmphasis [NUMERICAL]
#
# Attribute in nodes with depth <= 5:
# 	170 : LongRunHighGrayLevelEmphasis [NUMERICAL]
# 	79 : RunEntropy [NUMERICAL]
# 	73 : ShortRunHighGrayLevelEmphasis [NUMERICAL]
# 	56 : GrayLevelVariance [NUMERICAL]
# 	47 : HighGrayLevelRunEmphasis [NUMERICAL]
# 	39 : LongRunLowGrayLevelEmphasis [NUMERICAL]
# 	24 : LowGrayLevelRunEmphasis [NUMERICAL]
# 	24 : GrayLevelNonUniformity [NUMERICAL]
# 	18 : ShortRunLowGrayLevelEmphasis [NUMERICAL]
# 	14 : GrayLevelNonUniformityNormalized [NUMERICAL]
# 	12 : ShortRunEmphasis [NUMERICAL]
# 	12 : RunLengthNonUniformity [NUMERICAL]
# 	11 : RunLengthNonUniformityNormalized [NUMERICAL]
# 	7 : RunVariance [NUMERICAL]
# 	6 : RunPercentage [NUMERICAL]
# 	4 : LongRunEmphasis [NUMERICAL]
#
# Condition type in nodes:
# 	596 : HigherCondition
# Condition type in nodes with depth <= 0:
# 	27 : HigherCondition
# Condition type in nodes with depth <= 1:
# 	81 : HigherCondition
# Condition type in nodes with depth <= 2:
# 	180 : HigherCondition
# Condition type in nodes with depth <= 3:
# 	343 : HigherCondition
# Condition type in nodes with depth <= 5:
# 	596 : HigherCondition
#
# Training logs:
# Number of iteration to final model: 27
# 	Iter:1 train-loss:1.212468 valid-loss:1.228622  train-accuracy:0.970292 valid-accuracy:0.960614
# 	Iter:2 train-loss:1.068839 valid-loss:1.089159  train-accuracy:0.975940 valid-accuracy:0.960614
# 	Iter:3 train-loss:0.947672 valid-loss:0.967461  train-accuracy:0.980639 valid-accuracy:0.960614
# 	Iter:4 train-loss:0.844260 valid-loss:0.866384  train-accuracy:0.979690 valid-accuracy:0.956192
# 	Iter:5 train-loss:0.754111 valid-loss:0.792525  train-accuracy:0.982537 valid-accuracy:0.930074
# 	Iter:6 train-loss:0.681229 valid-loss:0.728088  train-accuracy:0.985813 valid-accuracy:0.925652
# 	Iter:16 train-loss:0.278347 valid-loss:0.409998  train-accuracy:0.990986 valid-accuracy:0.934497
# 	Iter:26 train-loss:0.145875 valid-loss:0.359785  train-accuracy:0.991935 valid-accuracy:0.930074
# 	Iter:36 train-loss:0.089408 valid-loss:0.369620  train-accuracy:0.994781 valid-accuracy:0.934497
# 	Iter:46 train-loss:0.061591 valid-loss:0.389116  train-accuracy:0.995730 valid-accuracy:0.934497
# 	Iter:56 train-loss:0.047390 valid-loss:0.412036  train-accuracy:0.997154 valid-accuracy:0.934497

# %%
# Model features
model.make_inspector().features()
# Out:
# ["GrayLevelNonUniformity" (1; #0),
#  "GrayLevelNonUniformityNormalized" (1; #1),
#  "GrayLevelVariance" (1; #2),
#  "HighGrayLevelRunEmphasis" (1; #3),
#  "LongRunEmphasis" (1; #4),
#  "LongRunHighGrayLevelEmphasis" (1; #5),
#  "LongRunLowGrayLevelEmphasis" (1; #6),
#  "LowGrayLevelRunEmphasis" (1; #7),
#  "RunEntropy" (1; #8),
#  "RunLengthNonUniformity" (1; #9),
#  "RunLengthNonUniformityNormalized" (1; #10),
#  "RunPercentage" (1; #11),
#  "RunVariance" (1; #12),
#  "ShortRunEmphasis" (1; #13),
#  "ShortRunHighGrayLevelEmphasis" (1; #14),
#  "ShortRunLowGrayLevelEmphasis" (1; #15)]

# %%
# Feature importance
model.make_inspector().variable_importances()
# Out:
# {'INV_MEAN_MIN_DEPTH': [("LongRunHighGrayLevelEmphasis" (1; #5), 1.0),
#   ("RunEntropy" (1; #8), 0.22001397417517918),
#   ("ShortRunHighGrayLevelEmphasis" (1; #14), 0.2181883453919449),
#   ("HighGrayLevelRunEmphasis" (1; #3), 0.2076772710788149),
#   ("GrayLevelVariance" (1; #2), 0.1904778003398601),
#   ("LongRunLowGrayLevelEmphasis" (1; #6), 0.1859447848280375),
#   ("GrayLevelNonUniformity" (1; #0), 0.182386305534781),
#   ("LowGrayLevelRunEmphasis" (1; #7), 0.17971261756637805),
#   ("RunLengthNonUniformity" (1; #9), 0.1793892958472917),
#   ("RunLengthNonUniformityNormalized" (1; #10), 0.17854985096850923),
#   ("ShortRunLowGrayLevelEmphasis" (1; #15), 0.17831465761124968),
#   ("RunPercentage" (1; #11), 0.178108980505424),
#   ("ShortRunEmphasis" (1; #13), 0.17777375098918666),
#   ("GrayLevelNonUniformityNormalized" (1; #1), 0.17721841254616308),
#   ("RunVariance" (1; #12), 0.17636397489376238),
#   ("LongRunEmphasis" (1; #4), 0.17569768492723642)],
#  'SUM_SCORE': [("LongRunHighGrayLevelEmphasis" (1; #5), 1261.6953805977216),
#   ("ShortRunHighGrayLevelEmphasis" (1; #14), 78.30122361021026),
#   ("RunEntropy" (1; #8), 73.23881850093112),
#   ("GrayLevelVariance" (1; #2), 31.654700812345066),
#   ("HighGrayLevelRunEmphasis" (1; #3), 26.109164372290067),
#   ("GrayLevelNonUniformity" (1; #0), 16.046541588527173),
#   ("LongRunLowGrayLevelEmphasis" (1; #6), 14.571730103498332),
#   ("LowGrayLevelRunEmphasis" (1; #7), 11.16029650683148),
#   ("RunLengthNonUniformity" (1; #9), 8.790969036033808),
#   ("RunVariance" (1; #12), 8.434711444208538),
#   ("ShortRunLowGrayLevelEmphasis" (1; #15), 8.116646153680348),
#   ("ShortRunEmphasis" (1; #13), 7.247277733660671),
#   ("RunPercentage" (1; #11), 3.5423105817266296),
#   ("LongRunEmphasis" (1; #4), 3.428072914918126),
#   ("RunLengthNonUniformityNormalized" (1; #10), 3.0445670921836165),
#   ("GrayLevelNonUniformityNormalized" (1; #1), 1.9561890353181641)],
#  'NUM_AS_ROOT': [("LongRunHighGrayLevelEmphasis" (1; #5), 27.0)],
#  'NUM_NODES': [("LongRunHighGrayLevelEmphasis" (1; #5), 170.0),
#   ("RunEntropy" (1; #8), 79.0),
#   ("ShortRunHighGrayLevelEmphasis" (1; #14), 73.0),
#   ("GrayLevelVariance" (1; #2), 56.0),
#   ("HighGrayLevelRunEmphasis" (1; #3), 47.0),
#   ("LongRunLowGrayLevelEmphasis" (1; #6), 39.0),
#   ("GrayLevelNonUniformity" (1; #0), 24.0),
#   ("LowGrayLevelRunEmphasis" (1; #7), 24.0),
#   ("ShortRunLowGrayLevelEmphasis" (1; #15), 18.0),
#   ("GrayLevelNonUniformityNormalized" (1; #1), 14.0),
#   ("RunLengthNonUniformity" (1; #9), 12.0),
#   ("ShortRunEmphasis" (1; #13), 12.0),
#   ("RunLengthNonUniformityNormalized" (1; #10), 11.0),
#   ("RunVariance" (1; #12), 7.0),
#   ("RunPercentage" (1; #11), 6.0),
#   ("LongRunEmphasis" (1; #4), 4.0)]}

# %%
# Model self evaluation
model.make_inspector().evaluation()
# Out:
# Evaluation(num_examples=None, accuracy=0.9300743341445923, loss=0.3496624529361725, rmse=None, ndcg=None, aucs=None, auuc=None, qini=None)

# %%
logs = model.make_inspector().training_logs()

plt.figure(figsize=(12, 4))
plt.subplot(1, 2, 1)
plt.plot([log.num_trees for log in logs], [log.evaluation.accuracy for log in logs])
plt.xlabel("Number of trees")
plt.ylabel("Accuracy (out-of-bag)")
plt.subplot(1, 2, 2)
plt.plot([log.num_trees for log in logs], [log.evaluation.loss for log in logs])
plt.xlabel("Number of trees")
plt.ylabel("Logloss (out-of-bag)")
plt.show()

# %% [markdown]
# Calculate the score of our hold-out validation dataset

# %%
predictions = model.predict(val_ds)
y_true      = validation_data["label"]

from sklearn.metrics import roc_auc_score
ROC_AUC = roc_auc_score(y_true, predictions)
print("The ROC AUC score is %.5f" % ROC_AUC )
# Out:
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 54ms/step
# The ROC AUC score is 0.99501

# %%
# Compute binary classification metrics with sklearn
import numpy as np
from sklearn.metrics import (
    accuracy_score,
    precision_score,
    recall_score,
    f1_score,
    roc_auc_score,
    average_precision_score,
    confusion_matrix,
    classification_report,
    matthews_corrcoef,
    log_loss,
    brier_score_loss,
)

# Get predictions (probabilities or class labels)
preds = model.predict(test_ds)
# If model outputs probabilities, convert to labels by threshold 0.5
if preds.ndim == 2:
    # For TFDF classification, preds may be class probabilities with shape (N, 2)
    if preds.shape[1] == 2:
        pos_probs = preds[:, 1]
    else:
        # If single-probability column (positive class)
        pos_probs = preds[:, -1]
    y_pred = (pos_probs >= 0.5).astype(int)
else:
    # Already class labels
    y_pred = preds.astype(int)
    pos_probs = None

# Ground truth labels (must be 0/1 integers)
y_true = test_data["label"].astype(int).to_numpy()

# Core metrics
metrics = {}
metrics["accuracy"] = accuracy_score(y_true, y_pred)
metrics["precision"] = precision_score(y_true, y_pred, zero_division=0)
metrics["recall"] = recall_score(y_true, y_pred, zero_division=0)
metrics["f1"] = f1_score(y_true, y_pred, zero_division=0)
metrics["mcc"] = matthews_corrcoef(y_true, y_pred)

# Probabilistic metrics (only if we have probabilities)
if pos_probs is not None:
    metrics["roc_auc"] = roc_auc_score(y_true, pos_probs)
    metrics["pr_auc"] = average_precision_score(y_true, pos_probs)
    metrics["log_loss"] = log_loss(y_true, pos_probs, labels=[0,1])
    metrics["brier_score"] = brier_score_loss(y_true, pos_probs)

# Confusion matrix and detailed report
cm = confusion_matrix(y_true, y_pred, labels=[0,1])
report = classification_report(y_true, y_pred, digits=4)

print("Sklearn binary metrics:")
for k, v in metrics.items():
    print(f"{k}: {v:.4f}")
print("\nConfusion matrix:\n", cm)
print("\nClassification report:\n", report)
# Out:
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 59ms/step
# Sklearn binary metrics:
# accuracy: 0.9503
# precision: 0.8475
# recall: 0.8333
# f1: 0.8403
# mcc: 0.8109
# roc_auc: 0.9782
# pr_auc: 0.9340
# log_loss: 0.1492
# brier_score: 0.0391
#
# Confusion matrix:
#  [[313   9]
#  [ 10  50]]
#
# Classification report:
#                precision    recall  f1-score   support
#
#            0     0.9690    0.9720    0.9705       322
#            1     0.8475    0.8333    0.8403        60
#
#     accuracy                         0.9503       382
#    macro avg     0.9082    0.9027    0.9054       382
# weighted avg     0.9499    0.9503    0.9501       382
