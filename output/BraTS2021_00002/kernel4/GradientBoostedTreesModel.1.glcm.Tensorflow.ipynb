# %%
# Import packages and modules
import numpy  as np
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow_decision_forests as tfdf

from sklearn.model_selection import train_test_split
# Out:
# 2026-08-12 05:36:19.594971: I tensorflow/core/util/port.cc:113] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2026-08-12 05:36:19.980029: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2026-08-12 05:36:24.344402: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
# Check the version of TensorFlow Decision Forests
print("Found TensorFlow Decision Forests v" + tfdf.__version__)
# Out:
# Found TensorFlow Decision Forests v1.9.1

# %%
datasetPath = 'dataset/firstorder/kernel5-radius5/dataset.csv'

# %%
# Parameters
datasetPath = "dataset/glcm/kernel4/1.dataset.csv"

# %%
# train/validation/test = 70/10/20
dataset = pd.read_csv(datasetPath)

train_data, temp_data = train_test_split(dataset, test_size=0.3, random_state=42)
validation_data, test_data = train_test_split(temp_data, test_size=2/3, random_state=42)

# %%
from sklearn.utils.class_weight import compute_class_weight

# tinh class weight tren tap train
classes = np.array([0, 1])
weights = compute_class_weight(class_weight="balanced", classes=classes, y=train_data["label"])
class_weight = {0: weights[0], 1: weights[1]}

# gan sample_weight cho tung dong
train_data["sample_weight"] = train_data["label"].map(class_weight)
validation_data["sample_weight"] = validation_data["label"].map(class_weight)
test_data["sample_weight"] = test_data["label"].map(class_weight)

# Convert the dataset into a TensorFlow dataset.
train_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    train_data, label="label", weight="sample_weight"
)         
val_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    validation_data, label="label", weight="sample_weight"
)
test_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    test_data, label="label", weight="sample_weight"
)
# Out:
# 2026-08-12 05:36:39.143272: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:984] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2026-08-12 05:36:39.144610: W tensorflow/core/common_runtime/gpu/gpu_device.cc:2251] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...

# %%
import keras

# %%
# %%time

# Train a Gradient Boosted Trees model.
model = tfdf.keras.GradientBoostedTreesModel()

# Add evaluation metrics
model.compile(
    metrics=["accuracy"]
)
model.fit(x=train_ds)

# # Train a Gradient Boosted Trees model.
# model = tfdf.keras.GradientBoostedTreesModel(num_trees=1500)
# model.fit(train_ds)
# Out:
# Use /tmp/tmp04865trk as temporary training directory
# Reading training dataset...
# [WARNING 26-08-12 05:36:39.2938 UTC gradient_boosted_trees.cc:1840] "goss_alpha" set but "sampling_method" not equal to "GOSS".
# [WARNING 26-08-12 05:36:39.2940 UTC gradient_boosted_trees.cc:1851] "goss_beta" set but "sampling_method" not equal to "GOSS".
# [WARNING 26-08-12 05:36:39.2940 UTC gradient_boosted_trees.cc:1865] "selective_gradient_boosting_ratio" set but "sampling_method" not equal to "SELGB".
# Training dataset read in 0:00:02.466733. Found 1336 examples.
# Training model...
# Model trained in 0:00:00.276493
# Compiling model...
# [INFO 26-08-12 05:36:42.0619 UTC kernel.cc:1233] Loading model from path /tmp/tmp04865trk/model/ with prefix 47f23b3d045f432c
# [INFO 26-08-12 05:36:42.0639 UTC quick_scorer_extended.cc:911] The binary was compiled without AVX2 support, but your CPU supports it. Enable it for faster model inference.
# [INFO 26-08-12 05:36:42.0640 UTC abstract_model.cc:1362] Engine "GradientBoostedTreesQuickScorerExtended" built
# [INFO 26-08-12 05:36:42.0640 UTC kernel.cc:1061] Use fast generic engine
# Model compiled.
# CPU times: user 5.75 s, sys: 434 ms, total: 6.18 s
# Wall time: 5.7 s

# %%
# Evaluate the model
evaluate = model.evaluate(val_ds, return_dict=True)
print()

for name, value in evaluate.items():
    print(f"{name}: {value:.4f}")
# Out:
# WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 1/1 [==============================] - ETA: 0s - loss: 0.0000e+00 - accuracy: 0.9581
# 1/1 [==============================] - 3s 3s/step - loss: 0.0000e+00 - accuracy: 0.9581
# loss: 0.0000
# accuracy: 0.9581

# %%
# Model Summary
model.summary()
# Out:
# Model: "gradient_boosted_trees_model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
# =================================================================
# Total params: 1 (1.00 Byte)
# Trainable params: 0 (0.00 Byte)
# Non-trainable params: 1 (1.00 Byte)
# _________________________________________________________________
# Type: "GRADIENT_BOOSTED_TREES"
# Task: CLASSIFICATION
# Label: "__LABEL"
#
# Input Features (24):
# 	Autocorrelation
# 	ClusterProminence
# 	ClusterShade
# 	ClusterTendency
# 	Contrast
# 	Correlation
# 	DifferenceAverage
# 	DifferenceEntropy
# 	DifferenceVariance
# 	Id
# 	Idm
# 	Idmn
# 	Idn
# 	Imc1
# 	Imc2
# 	InverseVariance
# 	JointAverage
# 	JointEnergy
# 	JointEntropy
# 	MCC
# 	MaximumProbability
# 	SumAverage
# 	SumEntropy
# 	SumSquares
#
# Trained with weights
#
# Variable Importance: INV_MEAN_MIN_DEPTH:
#     1.    "Autocorrelation"  1.000000 ################
#     2.        "Correlation"  0.246708 #
#     3.         "SumAverage"  0.217105
#     4.       "JointAverage"  0.206167
#     5.               "Imc1"  0.205084
#     6.                "MCC"  0.189608
#     7.       "ClusterShade"  0.188597
#     8. "MaximumProbability"  0.186225
#     9.                 "Id"  0.183343
#    10.    "InverseVariance"  0.181939
#    11.        "JointEnergy"  0.181659
#    12.                "Idm"  0.180136
#    13.               "Imc2"  0.178778
#    14.  "DifferenceEntropy"  0.177841
#    15.  "ClusterProminence"  0.177397
#    16. "DifferenceVariance"  0.177385
#    17.                "Idn"  0.177181
#    18.       "JointEntropy"  0.176324
#    19.         "SumEntropy"  0.176282
#    20.           "Contrast"  0.176277
#    21.    "ClusterTendency"  0.176263
#    22.               "Idmn"  0.176243
#    23.  "DifferenceAverage"  0.176218
#    24.         "SumSquares"  0.175954
#
# Variable Importance: NUM_AS_ROOT:
#     1. "Autocorrelation" 20.000000
#
# Variable Importance: NUM_NODES:
#     1.    "Autocorrelation" 63.000000 ################
#     2.        "Correlation" 63.000000 ################
#     3.         "SumAverage" 43.000000 ##########
#     4.       "ClusterShade" 39.000000 #########
#     5.                "MCC" 36.000000 #########
#     6.               "Imc1" 32.000000 ########
#     7.       "JointAverage" 32.000000 ########
#     8. "MaximumProbability" 23.000000 #####
#     9.                 "Id" 18.000000 ####
#    10.    "InverseVariance" 13.000000 ###
#    11.        "JointEnergy" 12.000000 ##
#    12.                "Idm" 11.000000 ##
#    13.               "Imc2"  9.000000 ##
#    14.  "DifferenceEntropy"  8.000000 #
#    15.  "ClusterProminence"  7.000000 #
#    16. "DifferenceVariance"  5.000000 #
#    17.                "Idn"  5.000000 #
#    18.  "DifferenceAverage"  3.000000
#    19.               "Idmn"  3.000000
#    20.         "SumEntropy"  3.000000
#    21.    "ClusterTendency"  2.000000
#    22.           "Contrast"  2.000000
#    23.       "JointEntropy"  2.000000
#    24.         "SumSquares"  1.000000
#
# Variable Importance: SUM_SCORE:
#     1.    "Autocorrelation" 1155.657028 ################
#     2.               "Imc1" 83.882163 #
#     3. "MaximumProbability" 61.843104
#     4.        "Correlation" 60.648895
#     5.         "SumAverage" 36.025368
#     6.    "InverseVariance" 24.815725
#     7.                 "Id" 21.741637
#     8.                "Idm" 17.069779
#     9.       "JointAverage" 14.443661
#    10.                "MCC" 14.374687
#    11.       "ClusterShade" 12.935864
#    12.        "JointEnergy" 11.411045
#    13.               "Imc2"  7.293930
#    14.  "ClusterProminence"  3.784198
#    15.         "SumEntropy"  3.222092
#    16. "DifferenceVariance"  1.597897
#    17.  "DifferenceEntropy"  0.747722
#    18.               "Idmn"  0.728248
#    19.                "Idn"  0.423341
#    20.           "Contrast"  0.106047
#    21.  "DifferenceAverage"  0.092782
#    22.       "JointEntropy"  0.034722
#    23.    "ClusterTendency"  0.010750
#    24.         "SumSquares"  0.000386
#
#
#
# Loss: BINOMIAL_LOG_LIKELIHOOD
# Validation loss value: 0.521309
# Number of trees per iteration: 1
# Node format: NOT_SET
# Number of trees: 20
# Total number of nodes: 890
#
# Number of nodes by tree:
# Count: 20 Average: 44.5 StdDev: 4.09268
# Min: 35 Max: 53 Ignored: 0
# ----------------------------------------------
# [ 35, 36) 1   5.00%   5.00% #
# [ 36, 37) 0   0.00%   5.00%
# [ 37, 38) 1   5.00%  10.00% #
# [ 38, 39) 0   0.00%  10.00%
# [ 39, 40) 1   5.00%  15.00% #
# [ 40, 41) 0   0.00%  15.00%
# [ 41, 42) 2  10.00%  25.00% ##
# [ 42, 43) 0   0.00%  25.00%
# [ 43, 44) 2  10.00%  35.00% ##
# [ 44, 45) 0   0.00%  35.00%
# [ 45, 46) 3  15.00%  50.00% ###
# [ 46, 47) 0   0.00%  50.00%
# [ 47, 48) 9  45.00%  95.00% ##########
# [ 48, 49) 0   0.00%  95.00%
# [ 49, 50) 0   0.00%  95.00%
# [ 50, 51) 0   0.00%  95.00%
# [ 51, 52) 0   0.00%  95.00%
# [ 52, 53) 0   0.00%  95.00%
# [ 53, 53] 1   5.00% 100.00% #
#
# Depth by leafs:
# Count: 455 Average: 4.69451 StdDev: 0.629907
# Min: 2 Max: 5 Ignored: 0
# ----------------------------------------------
# [ 2, 3)   4   0.88%   0.88%
# [ 3, 4)  30   6.59%   7.47% #
# [ 4, 5)  67  14.73%  22.20% ##
# [ 5, 5] 354  77.80% 100.00% ##########
#
# Number of training obs by leaf:
# Count: 455 Average: 53.978 StdDev: 152.889
# Min: 5 Max: 780 Ignored: 0
# ----------------------------------------------
# [   5,  43) 378  83.08%  83.08% ##########
# [  43,  82)  21   4.62%  87.69% #
# [  82, 121)  31   6.81%  94.51% #
# [ 121, 160)   4   0.88%  95.38%
# [ 160, 199)   1   0.22%  95.60%
# [ 199, 237)   0   0.00%  95.60%
# [ 237, 276)   0   0.00%  95.60%
# [ 276, 315)   0   0.00%  95.60%
# [ 315, 354)   0   0.00%  95.60%
# [ 354, 393)   0   0.00%  95.60%
# [ 393, 431)   0   0.00%  95.60%
# [ 431, 470)   0   0.00%  95.60%
# [ 470, 509)   0   0.00%  95.60%
# [ 509, 548)   0   0.00%  95.60%
# [ 548, 587)   0   0.00%  95.60%
# [ 587, 625)   0   0.00%  95.60%
# [ 625, 664)   1   0.22%  95.82%
# [ 664, 703)   0   0.00%  95.82%
# [ 703, 742)   5   1.10%  96.92%
# [ 742, 780]  14   3.08% 100.00%
#
# Attribute in nodes:
# 	63 : Correlation [NUMERICAL]
# 	63 : Autocorrelation [NUMERICAL]
# 	43 : SumAverage [NUMERICAL]
# 	39 : ClusterShade [NUMERICAL]
# 	36 : MCC [NUMERICAL]
# 	32 : JointAverage [NUMERICAL]
# 	32 : Imc1 [NUMERICAL]
# 	23 : MaximumProbability [NUMERICAL]
# 	18 : Id [NUMERICAL]
# 	13 : InverseVariance [NUMERICAL]
# 	12 : JointEnergy [NUMERICAL]
# 	11 : Idm [NUMERICAL]
# 	9 : Imc2 [NUMERICAL]
# 	8 : DifferenceEntropy [NUMERICAL]
# 	7 : ClusterProminence [NUMERICAL]
# 	5 : Idn [NUMERICAL]
# 	5 : DifferenceVariance [NUMERICAL]
# 	3 : SumEntropy [NUMERICAL]
# 	3 : Idmn [NUMERICAL]
# 	3 : DifferenceAverage [NUMERICAL]
# 	2 : JointEntropy [NUMERICAL]
# 	2 : Contrast [NUMERICAL]
# 	2 : ClusterTendency [NUMERICAL]
# 	1 : SumSquares [NUMERICAL]
#
# Attribute in nodes with depth <= 0:
# 	20 : Autocorrelation [NUMERICAL]
#
# Attribute in nodes with depth <= 1:
# 	35 : Autocorrelation [NUMERICAL]
# 	15 : Correlation [NUMERICAL]
# 	5 : SumAverage [NUMERICAL]
# 	5 : JointAverage [NUMERICAL]
#
# Attribute in nodes with depth <= 2:
# 	39 : Autocorrelation [NUMERICAL]
# 	22 : Correlation [NUMERICAL]
# 	16 : Imc1 [NUMERICAL]
# 	14 : SumAverage [NUMERICAL]
# 	13 : MCC [NUMERICAL]
# 	10 : JointAverage [NUMERICAL]
# 	7 : ClusterShade [NUMERICAL]
# 	4 : MaximumProbability [NUMERICAL]
# 	2 : Id [NUMERICAL]
# 	2 : DifferenceVariance [NUMERICAL]
# 	1 : SumEntropy [NUMERICAL]
# 	1 : JointEnergy [NUMERICAL]
# 	1 : InverseVariance [NUMERICAL]
# 	1 : Imc2 [NUMERICAL]
# 	1 : Idm [NUMERICAL]
# 	1 : DifferenceEntropy [NUMERICAL]
# 	1 : ClusterProminence [NUMERICAL]
#
# Attribute in nodes with depth <= 3:
# 	46 : Autocorrelation [NUMERICAL]
# 	37 : Correlation [NUMERICAL]
# 	30 : SumAverage [NUMERICAL]
# 	25 : Imc1 [NUMERICAL]
# 	21 : MCC [NUMERICAL]
# 	21 : JointAverage [NUMERICAL]
# 	14 : ClusterShade [NUMERICAL]
# 	11 : MaximumProbability [NUMERICAL]
# 	10 : InverseVariance [NUMERICAL]
# 	10 : Id [NUMERICAL]
# 	8 : JointEnergy [NUMERICAL]
# 	5 : Idm [NUMERICAL]
# 	4 : Imc2 [NUMERICAL]
# 	3 : Idn [NUMERICAL]
# 	3 : DifferenceEntropy [NUMERICAL]
# 	2 : DifferenceVariance [NUMERICAL]
# 	2 : ClusterTendency [NUMERICAL]
# 	2 : ClusterProminence [NUMERICAL]
# 	1 : SumEntropy [NUMERICAL]
# 	1 : JointEntropy [NUMERICAL]
# 	1 : Idmn [NUMERICAL]
# 	1 : Contrast [NUMERICAL]
#
# Attribute in nodes with depth <= 5:
# 	63 : Correlation [NUMERICAL]
# 	63 : Autocorrelation [NUMERICAL]
# 	43 : SumAverage [NUMERICAL]
# 	39 : ClusterShade [NUMERICAL]
# 	36 : MCC [NUMERICAL]
# 	32 : JointAverage [NUMERICAL]
# 	32 : Imc1 [NUMERICAL]
# 	23 : MaximumProbability [NUMERICAL]
# 	18 : Id [NUMERICAL]
# 	13 : InverseVariance [NUMERICAL]
# 	12 : JointEnergy [NUMERICAL]
# 	11 : Idm [NUMERICAL]
# 	9 : Imc2 [NUMERICAL]
# 	8 : DifferenceEntropy [NUMERICAL]
# 	7 : ClusterProminence [NUMERICAL]
# 	5 : Idn [NUMERICAL]
# 	5 : DifferenceVariance [NUMERICAL]
# 	3 : SumEntropy [NUMERICAL]
# 	3 : Idmn [NUMERICAL]
# 	3 : DifferenceAverage [NUMERICAL]
# 	2 : JointEntropy [NUMERICAL]
# 	2 : Contrast [NUMERICAL]
# 	2 : ClusterTendency [NUMERICAL]
# 	1 : SumSquares [NUMERICAL]
#
# Condition type in nodes:
# 	435 : HigherCondition
# Condition type in nodes with depth <= 0:
# 	20 : HigherCondition
# Condition type in nodes with depth <= 1:
# 	60 : HigherCondition
# Condition type in nodes with depth <= 2:
# 	136 : HigherCondition
# Condition type in nodes with depth <= 3:
# 	258 : HigherCondition
# Condition type in nodes with depth <= 5:
# 	435 : HigherCondition
#
# Training logs:
# Number of iteration to final model: 20
# 	Iter:1 train-loss:1.216078 valid-loss:1.243978  train-accuracy:0.965203 valid-accuracy:0.891138
# 	Iter:2 train-loss:1.076527 valid-loss:1.129131  train-accuracy:0.968536 valid-accuracy:0.896289
# 	Iter:3 train-loss:0.960086 valid-loss:1.034851  train-accuracy:0.969012 valid-accuracy:0.896289
# 	Iter:4 train-loss:0.854592 valid-loss:0.951306  train-accuracy:0.978570 valid-accuracy:0.901439
# 	Iter:5 train-loss:0.770036 valid-loss:0.888074  train-accuracy:0.971902 valid-accuracy:0.896289
# 	Iter:6 train-loss:0.696642 valid-loss:0.832292  train-accuracy:0.973807 valid-accuracy:0.896289
# 	Iter:16 train-loss:0.291460 valid-loss:0.557617  train-accuracy:0.983332 valid-accuracy:0.911739
# 	Iter:26 train-loss:0.151088 valid-loss:0.527784  train-accuracy:0.988571 valid-accuracy:0.911739
# 	Iter:36 train-loss:0.089461 valid-loss:0.565131  train-accuracy:0.994761 valid-accuracy:0.911739
# 	Iter:46 train-loss:0.059071 valid-loss:0.609722  train-accuracy:0.998095 valid-accuracy:0.911739

# %%
# Model features
model.make_inspector().features()
# Out:
# ["Autocorrelation" (1; #0),
#  "ClusterProminence" (1; #1),
#  "ClusterShade" (1; #2),
#  "ClusterTendency" (1; #3),
#  "Contrast" (1; #4),
#  "Correlation" (1; #5),
#  "DifferenceAverage" (1; #6),
#  "DifferenceEntropy" (1; #7),
#  "DifferenceVariance" (1; #8),
#  "Id" (1; #9),
#  "Idm" (1; #10),
#  "Idmn" (1; #11),
#  "Idn" (1; #12),
#  "Imc1" (1; #13),
#  "Imc2" (1; #14),
#  "InverseVariance" (1; #15),
#  "JointAverage" (1; #16),
#  "JointEnergy" (1; #17),
#  "JointEntropy" (1; #18),
#  "MCC" (1; #19),
#  "MaximumProbability" (1; #20),
#  "SumAverage" (1; #21),
#  "SumEntropy" (1; #22),
#  "SumSquares" (1; #23)]

# %%
# Feature importance
model.make_inspector().variable_importances()
# Out:
# {'INV_MEAN_MIN_DEPTH': [("Autocorrelation" (1; #0), 1.0),
#   ("Correlation" (1; #5), 0.24670818119408033),
#   ("SumAverage" (1; #21), 0.2171045953921027),
#   ("JointAverage" (1; #16), 0.20616742808367833),
#   ("Imc1" (1; #13), 0.20508443764072445),
#   ("MCC" (1; #19), 0.18960847982245022),
#   ("ClusterShade" (1; #2), 0.1885970628851857),
#   ("MaximumProbability" (1; #20), 0.18622516675964637),
#   ("Id" (1; #9), 0.1833429704767771),
#   ("InverseVariance" (1; #15), 0.18193877107252812),
#   ("JointEnergy" (1; #17), 0.1816585356643311),
#   ("Idm" (1; #10), 0.18013612342961285),
#   ("Imc2" (1; #14), 0.17877833537884302),
#   ("DifferenceEntropy" (1; #7), 0.17784092146233288),
#   ("ClusterProminence" (1; #1), 0.1773967740831581),
#   ("DifferenceVariance" (1; #8), 0.1773848545752138),
#   ("Idn" (1; #12), 0.17718083050793026),
#   ("JointEntropy" (1; #18), 0.17632366563246155),
#   ("SumEntropy" (1; #22), 0.1762817287364209),
#   ("Contrast" (1; #4), 0.17627710009720252),
#   ("ClusterTendency" (1; #3), 0.1762630280249948),
#   ("Idmn" (1; #11), 0.1762429492614079),
#   ("DifferenceAverage" (1; #6), 0.17621832501668952),
#   ("SumSquares" (1; #23), 0.17595432145457174)],
#  'SUM_SCORE': [("Autocorrelation" (1; #0), 1155.6570277718306),
#   ("Imc1" (1; #13), 83.88216316441873),
#   ("MaximumProbability" (1; #20), 61.843104199439296),
#   ("Correlation" (1; #5), 60.648894866103575),
#   ("SumAverage" (1; #21), 36.02536838810943),
#   ("InverseVariance" (1; #15), 24.815724923690194),
#   ("Id" (1; #9), 21.741636564058055),
#   ("Idm" (1; #10), 17.069778571794266),
#   ("JointAverage" (1; #16), 14.443660811713354),
#   ("MCC" (1; #19), 14.374686837076409),
#   ("ClusterShade" (1; #2), 12.93586368336575),
#   ("JointEnergy" (1; #17), 11.41104531065871),
#   ("Imc2" (1; #14), 7.293929787645278),
#   ("ClusterProminence" (1; #1), 3.784198194957049),
#   ("SumEntropy" (1; #22), 3.2220920576312553),
#   ("DifferenceVariance" (1; #8), 1.5978974294667958),
#   ("DifferenceEntropy" (1; #7), 0.7477221632890427),
#   ("Idmn" (1; #11), 0.7282475994933915),
#   ("Idn" (1; #12), 0.42334056986851865),
#   ("Contrast" (1; #4), 0.10604694561408863),
#   ("DifferenceAverage" (1; #6), 0.092781939887046),
#   ("JointEntropy" (1; #18), 0.03472234916275692),
#   ("ClusterTendency" (1; #3), 0.010749641638285373),
#   ("SumSquares" (1; #23), 0.0003860146422169793)],
#  'NUM_AS_ROOT': [("Autocorrelation" (1; #0), 20.0)],
#  'NUM_NODES': [("Autocorrelation" (1; #0), 63.0),
#   ("Correlation" (1; #5), 63.0),
#   ("SumAverage" (1; #21), 43.0),
#   ("ClusterShade" (1; #2), 39.0),
#   ("MCC" (1; #19), 36.0),
#   ("Imc1" (1; #13), 32.0),
#   ("JointAverage" (1; #16), 32.0),
#   ("MaximumProbability" (1; #20), 23.0),
#   ("Id" (1; #9), 18.0),
#   ("InverseVariance" (1; #15), 13.0),
#   ("JointEnergy" (1; #17), 12.0),
#   ("Idm" (1; #10), 11.0),
#   ("Imc2" (1; #14), 9.0),
#   ("DifferenceEntropy" (1; #7), 8.0),
#   ("ClusterProminence" (1; #1), 7.0),
#   ("DifferenceVariance" (1; #8), 5.0),
#   ("Idn" (1; #12), 5.0),
#   ("DifferenceAverage" (1; #6), 3.0),
#   ("Idmn" (1; #11), 3.0),
#   ("SumEntropy" (1; #22), 3.0),
#   ("ClusterTendency" (1; #3), 2.0),
#   ("Contrast" (1; #4), 2.0),
#   ("JointEntropy" (1; #18), 2.0),
#   ("SumSquares" (1; #23), 1.0)]}

# %%
# Model self evaluation
model.make_inspector().evaluation()
# Out:
# Evaluation(num_examples=None, accuracy=0.9117390513420105, loss=0.5213093161582947, rmse=None, ndcg=None, aucs=None, auuc=None, qini=None)

# %%
logs = model.make_inspector().training_logs()

plt.figure(figsize=(12, 4))
plt.subplot(1, 2, 1)
plt.plot([log.num_trees for log in logs], [log.evaluation.accuracy for log in logs])
plt.xlabel("Number of trees")
plt.ylabel("Accuracy (out-of-bag)")
plt.subplot(1, 2, 2)
plt.plot([log.num_trees for log in logs], [log.evaluation.loss for log in logs])
plt.xlabel("Number of trees")
plt.ylabel("Logloss (out-of-bag)")
plt.show()

# %% [markdown]
# Calculate the score of our hold-out validation dataset

# %%
predictions = model.predict(val_ds)
y_true      = validation_data["label"]

from sklearn.metrics import roc_auc_score
ROC_AUC = roc_auc_score(y_true, predictions)
print("The ROC AUC score is %.5f" % ROC_AUC )
# Out:
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 61ms/step
# The ROC AUC score is 0.97835

# %%
# Compute binary classification metrics with sklearn
import numpy as np
from sklearn.metrics import (
    accuracy_score,
    precision_score,
    recall_score,
    f1_score,
    roc_auc_score,
    average_precision_score,
    confusion_matrix,
    classification_report,
    matthews_corrcoef,
    log_loss,
    brier_score_loss,
)

# Get predictions (probabilities or class labels)
preds = model.predict(test_ds)
# If model outputs probabilities, convert to labels by threshold 0.5
if preds.ndim == 2:
    # For TFDF classification, preds may be class probabilities with shape (N, 2)
    if preds.shape[1] == 2:
        pos_probs = preds[:, 1]
    else:
        # If single-probability column (positive class)
        pos_probs = preds[:, -1]
    y_pred = (pos_probs >= 0.5).astype(int)
else:
    # Already class labels
    y_pred = preds.astype(int)
    pos_probs = None

# Ground truth labels (must be 0/1 integers)
y_true = test_data["label"].astype(int).to_numpy()

# Core metrics
metrics = {}
metrics["accuracy"] = accuracy_score(y_true, y_pred)
metrics["precision"] = precision_score(y_true, y_pred, zero_division=0)
metrics["recall"] = recall_score(y_true, y_pred, zero_division=0)
metrics["f1"] = f1_score(y_true, y_pred, zero_division=0)
metrics["mcc"] = matthews_corrcoef(y_true, y_pred)

# Probabilistic metrics (only if we have probabilities)
if pos_probs is not None:
    metrics["roc_auc"] = roc_auc_score(y_true, pos_probs)
    metrics["pr_auc"] = average_precision_score(y_true, pos_probs)
    metrics["log_loss"] = log_loss(y_true, pos_probs, labels=[0,1])
    metrics["brier_score"] = brier_score_loss(y_true, pos_probs)

# Confusion matrix and detailed report
cm = confusion_matrix(y_true, y_pred, labels=[0,1])
report = classification_report(y_true, y_pred, digits=4)

print("Sklearn binary metrics:")
for k, v in metrics.items():
    print(f"{k}: {v:.4f}")
print("\nConfusion matrix:\n", cm)
print("\nClassification report:\n", report)
# Out:
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 69ms/step
# Sklearn binary metrics:
# accuracy: 0.9581
# precision: 0.8070
# recall: 0.9020
# f1: 0.8519
# mcc: 0.8293
# roc_auc: 0.9810
# pr_auc: 0.9336
# log_loss: 0.1634
# brier_score: 0.0384
#
# Confusion matrix:
#  [[320  11]
#  [  5  46]]
#
# Classification report:
#                precision    recall  f1-score   support
#
#            0     0.9846    0.9668    0.9756       331
#            1     0.8070    0.9020    0.8519        51
#
#     accuracy                         0.9581       382
#    macro avg     0.8958    0.9344    0.9137       382
# weighted avg     0.9609    0.9581    0.9591       382
