# %%
# Import packages and modules
import numpy  as np
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow_decision_forests as tfdf

from sklearn.model_selection import train_test_split
# Out:
# 2026-08-13 04:24:33.579688: I tensorflow/core/util/port.cc:113] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2026-08-13 04:24:33.961297: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2026-08-13 04:24:39.230835: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
# Check the version of TensorFlow Decision Forests
print("Found TensorFlow Decision Forests v" + tfdf.__version__)
# Out:
# Found TensorFlow Decision Forests v1.9.1

# %%
datasetPath = 'dataset/firstorder/kernel5/dataset.csv'

# %%
# Parameters
datasetPath = "dataset/glszm/kernel3/1.dataset.csv"

# %%
# train/validation/test = 70/10/20
dataset = pd.read_csv(datasetPath)

train_data, temp_data = train_test_split(dataset, test_size=0.3, random_state=42)
validation_data, test_data = train_test_split(temp_data, test_size=2/3, random_state=42)

# %%
from sklearn.utils.class_weight import compute_class_weight

# tinh class weight tren tap train
classes = np.array([0, 1])
weights = compute_class_weight(class_weight="balanced", classes=classes, y=train_data["label"])
class_weight = {0: weights[0], 1: weights[1]}

# gan sample_weight cho tung dong
train_data["sample_weight"] = train_data["label"].map(class_weight)
validation_data["sample_weight"] = validation_data["label"].map(class_weight)
test_data["sample_weight"] = test_data["label"].map(class_weight)

# Convert the dataset into a TensorFlow dataset.
train_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    train_data, label="label", weight="sample_weight"
)         
val_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    validation_data, label="label", weight="sample_weight"
)
test_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    test_data, label="label", weight="sample_weight"
)
# Out:
# 2026-08-13 04:24:53.214081: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:984] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2026-08-13 04:24:53.215570: W tensorflow/core/common_runtime/gpu/gpu_device.cc:2251] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...

# %%
import keras

# %%
# %%time

# Train a Random Forest model.
model = tfdf.keras.RandomForestModel()

# Add evaluation metrics
model.compile(
    metrics=["accuracy"]
)
model.fit(x=train_ds)

# # Train a Gradient Boosted Trees model.
# model = tfdf.keras.GradientBoostedTreesModel(num_trees=1500)
# model.fit(train_ds)
# Out:
# Use /tmp/tmpyhgglewd as temporary training directory
# Reading training dataset...
# Training dataset read in 0:00:02.681339. Found 2835 examples.
# Training model...
# Model trained in 0:00:00.199747
# Compiling model...
# [INFO 26-08-13 04:24:56.2249 UTC kernel.cc:1233] Loading model from path /tmp/tmpyhgglewd/model/ with prefix f1b888dca8554878
# [INFO 26-08-13 04:24:56.2725 UTC decision_forest.cc:734] Model loaded with 300 root(s), 36302 node(s), and 16 input feature(s).
# [INFO 26-08-13 04:24:56.2725 UTC abstract_model.cc:1362] Engine "RandomForestOptPred" built
# [INFO 26-08-13 04:24:56.2725 UTC kernel.cc:1061] Use fast generic engine
# Model compiled.
# CPU times: user 6.58 s, sys: 122 ms, total: 6.7 s
# Wall time: 6.18 s

# %%
# Evaluate the model
evaluate = model.evaluate(val_ds, return_dict=True)
print()

for name, value in evaluate.items():
    print(f"{name}: {value:.4f}")
# Out:
# WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 1/1 [==============================] - ETA: 0s - loss: 0.0000e+00 - accuracy: 0.9630
# 1/1 [==============================] - 3s 3s/step - loss: 0.0000e+00 - accuracy: 0.9630
# loss: 0.0000
# accuracy: 0.9630

# %%
# Model Summary
model.summary()
# Out:
# Model: "random_forest_model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
# =================================================================
# Total params: 1 (1.00 Byte)
# Trainable params: 0 (0.00 Byte)
# Non-trainable params: 1 (1.00 Byte)
# _________________________________________________________________
# Type: "RANDOM_FOREST"
# Task: CLASSIFICATION
# Label: "__LABEL"
#
# Input Features (16):
# 	GrayLevelNonUniformity
# 	GrayLevelNonUniformityNormalized
# 	GrayLevelVariance
# 	HighGrayLevelZoneEmphasis
# 	LargeAreaEmphasis
# 	LargeAreaHighGrayLevelEmphasis
# 	LargeAreaLowGrayLevelEmphasis
# 	LowGrayLevelZoneEmphasis
# 	SizeZoneNonUniformity
# 	SizeZoneNonUniformityNormalized
# 	SmallAreaEmphasis
# 	SmallAreaHighGrayLevelEmphasis
# 	SmallAreaLowGrayLevelEmphasis
# 	ZoneEntropy
# 	ZonePercentage
# 	ZoneVariance
#
# Trained with weights
#
# Variable Importance: INV_MEAN_MIN_DEPTH:
#     1.        "HighGrayLevelZoneEmphasis"  0.262057 ################
#     2.         "LowGrayLevelZoneEmphasis"  0.213870 ##########
#     3.           "GrayLevelNonUniformity"  0.194108 #######
#     4.   "LargeAreaHighGrayLevelEmphasis"  0.174321 #####
#     5.   "SmallAreaHighGrayLevelEmphasis"  0.174023 #####
#     6.    "SmallAreaLowGrayLevelEmphasis"  0.172194 #####
#     7.    "LargeAreaLowGrayLevelEmphasis"  0.150611 ##
#     8.                "GrayLevelVariance"  0.136662
#     9.                     "ZoneVariance"  0.136013
#    10. "GrayLevelNonUniformityNormalized"  0.135405
#    11.                "LargeAreaEmphasis"  0.133575
#    12.                      "ZoneEntropy"  0.132923
#    13.            "SizeZoneNonUniformity"  0.130049
#    14.  "SizeZoneNonUniformityNormalized"  0.129503
#    15.                   "ZonePercentage"  0.129114
#    16.                "SmallAreaEmphasis"  0.128824
#
# Variable Importance: NUM_AS_ROOT:
#     1.       "HighGrayLevelZoneEmphasis" 93.000000 ################
#     2.        "LowGrayLevelZoneEmphasis" 82.000000 ##############
#     3.   "SmallAreaLowGrayLevelEmphasis" 47.000000 ########
#     4.  "SmallAreaHighGrayLevelEmphasis" 22.000000 ###
#     5.  "LargeAreaHighGrayLevelEmphasis" 21.000000 ###
#     6.   "LargeAreaLowGrayLevelEmphasis" 12.000000 #
#     7.          "GrayLevelNonUniformity" 11.000000 #
#     8. "SizeZoneNonUniformityNormalized"  6.000000
#     9.               "SmallAreaEmphasis"  3.000000
#    10.                     "ZoneEntropy"  2.000000
#    11.           "SizeZoneNonUniformity"  1.000000
#
# Variable Importance: NUM_NODES:
#     1.           "GrayLevelNonUniformity" 1809.000000 ################
#     2.        "HighGrayLevelZoneEmphasis" 1708.000000 ##############
#     3.   "LargeAreaHighGrayLevelEmphasis" 1552.000000 ############
#     4.         "LowGrayLevelZoneEmphasis" 1470.000000 ###########
#     5.    "LargeAreaLowGrayLevelEmphasis" 1261.000000 ########
#     6.   "SmallAreaHighGrayLevelEmphasis" 1219.000000 #######
#     7.    "SmallAreaLowGrayLevelEmphasis" 1092.000000 #####
#     8. "GrayLevelNonUniformityNormalized" 1052.000000 #####
#     9.                "GrayLevelVariance" 986.000000 ####
#    10.                     "ZoneVariance" 962.000000 ###
#    11.                      "ZoneEntropy" 954.000000 ###
#    12.                "LargeAreaEmphasis" 878.000000 ##
#    13.                "SmallAreaEmphasis" 811.000000 #
#    14.            "SizeZoneNonUniformity" 785.000000 #
#    15.  "SizeZoneNonUniformityNormalized" 766.000000 #
#    16.                   "ZonePercentage" 696.000000
#
# Variable Importance: SUM_SCORE:
#     1.        "HighGrayLevelZoneEmphasis" 151845.716789 ################
#     2.         "LowGrayLevelZoneEmphasis" 111650.752261 ###########
#     3.    "SmallAreaLowGrayLevelEmphasis" 68179.175310 ######
#     4.   "SmallAreaHighGrayLevelEmphasis" 48714.329921 ####
#     5.           "GrayLevelNonUniformity" 42227.604433 ###
#     6.   "LargeAreaHighGrayLevelEmphasis" 33008.245688 ##
#     7.    "LargeAreaLowGrayLevelEmphasis" 20743.085449 #
#     8. "GrayLevelNonUniformityNormalized" 12734.136188
#     9.                "GrayLevelVariance" 11786.228067
#    10.                     "ZoneVariance" 10255.715951
#    11.                      "ZoneEntropy" 10225.538963
#    12.                "LargeAreaEmphasis" 8983.120629
#    13.            "SizeZoneNonUniformity" 7701.565565
#    14.                "SmallAreaEmphasis" 7428.105759
#    15.  "SizeZoneNonUniformityNormalized" 6944.802011
#    16.                   "ZonePercentage" 6339.670779
#
#
#
# Winner takes all: true
# Out-of-bag evaluation: accuracy:0.898819 logloss:0.262491
# Number of trees: 300
# Total number of nodes: 36302
#
# Number of nodes by tree:
# Count: 300 Average: 121.007 StdDev: 8.82949
# Min: 97 Max: 143 Ignored: 0
# ----------------------------------------------
# [  97,  99)  1   0.33%   0.33%
# [  99, 101)  2   0.67%   1.00%
# [ 101, 104)  5   1.67%   2.67% #
# [ 104, 106)  5   1.67%   4.33% #
# [ 106, 108)  6   2.00%   6.33% #
# [ 108, 111)  9   3.00%   9.33% ##
# [ 111, 113) 12   4.00%  13.33% ##
# [ 113, 115) 18   6.00%  19.33% ###
# [ 115, 118) 60  20.00%  39.33% ##########
# [ 118, 120) 33  11.00%  50.33% ######
# [ 120, 122) 14   4.67%  55.00% ##
# [ 122, 125) 27   9.00%  64.00% #####
# [ 125, 127) 26   8.67%  72.67% ####
# [ 127, 129) 24   8.00%  80.67% ####
# [ 129, 132) 29   9.67%  90.33% #####
# [ 132, 134)  5   1.67%  92.00% #
# [ 134, 136)  5   1.67%  93.67% #
# [ 136, 139)  5   1.67%  95.33% #
# [ 139, 141)  7   2.33%  97.67% #
# [ 141, 143]  7   2.33% 100.00% #
#
# Depth by leafs:
# Count: 18301 Average: 7.33818 StdDev: 2.1931
# Min: 2 Max: 15 Ignored: 0
# ----------------------------------------------
# [  2,  3)   80   0.44%   0.44%
# [  3,  4)  417   2.28%   2.72% #
# [  4,  5) 1137   6.21%   8.93% ###
# [  5,  6) 2080  11.37%  20.29% ######
# [  6,  7) 3032  16.57%  36.86% #########
# [  7,  8) 3364  18.38%  55.24% ##########
# [  8,  9) 3053  16.68%  71.93% #########
# [  9, 10) 2197  12.00%  83.93% #######
# [ 10, 11) 1458   7.97%  91.90% ####
# [ 11, 12)  801   4.38%  96.27% ##
# [ 12, 13)  404   2.21%  98.48% #
# [ 13, 14)  161   0.88%  99.36%
# [ 14, 15)   87   0.48%  99.84%
# [ 15, 15]   30   0.16% 100.00%
#
# Number of training obs by leaf:
# Count: 18301 Average: 46.4729 StdDev: 143.277
# Min: 5 Max: 1524 Ignored: 0
# ----------------------------------------------
# [    5,   81) 16398  89.60%  89.60% ##########
# [   81,  157)   717   3.92%  93.52%
# [  157,  233)   407   2.22%  95.74%
# [  233,  309)   122   0.67%  96.41%
# [  309,  385)   106   0.58%  96.99%
# [  385,  461)    88   0.48%  97.47%
# [  461,  537)    58   0.32%  97.79%
# [  537,  613)    55   0.30%  98.09%
# [  613,  689)    51   0.28%  98.37%
# [  689,  765)    42   0.23%  98.60%
# [  765,  841)    33   0.18%  98.78%
# [  841,  917)    56   0.31%  99.08%
# [  917,  993)    33   0.18%  99.26%
# [  993, 1069)    48   0.26%  99.52%
# [ 1069, 1145)    31   0.17%  99.69%
# [ 1145, 1221)    21   0.11%  99.81%
# [ 1221, 1297)    21   0.11%  99.92%
# [ 1297, 1373)     6   0.03%  99.96%
# [ 1373, 1449)     4   0.02%  99.98%
# [ 1449, 1524]     4   0.02% 100.00%
#
# Attribute in nodes:
# 	1809 : GrayLevelNonUniformity [NUMERICAL]
# 	1708 : HighGrayLevelZoneEmphasis [NUMERICAL]
# 	1552 : LargeAreaHighGrayLevelEmphasis [NUMERICAL]
# 	1470 : LowGrayLevelZoneEmphasis [NUMERICAL]
# 	1261 : LargeAreaLowGrayLevelEmphasis [NUMERICAL]
# 	1219 : SmallAreaHighGrayLevelEmphasis [NUMERICAL]
# 	1092 : SmallAreaLowGrayLevelEmphasis [NUMERICAL]
# 	1052 : GrayLevelNonUniformityNormalized [NUMERICAL]
# 	986 : GrayLevelVariance [NUMERICAL]
# 	962 : ZoneVariance [NUMERICAL]
# 	954 : ZoneEntropy [NUMERICAL]
# 	878 : LargeAreaEmphasis [NUMERICAL]
# 	811 : SmallAreaEmphasis [NUMERICAL]
# 	785 : SizeZoneNonUniformity [NUMERICAL]
# 	766 : SizeZoneNonUniformityNormalized [NUMERICAL]
# 	696 : ZonePercentage [NUMERICAL]
#
# Attribute in nodes with depth <= 0:
# 	93 : HighGrayLevelZoneEmphasis [NUMERICAL]
# 	82 : LowGrayLevelZoneEmphasis [NUMERICAL]
# 	47 : SmallAreaLowGrayLevelEmphasis [NUMERICAL]
# 	22 : SmallAreaHighGrayLevelEmphasis [NUMERICAL]
# 	21 : LargeAreaHighGrayLevelEmphasis [NUMERICAL]
# 	12 : LargeAreaLowGrayLevelEmphasis [NUMERICAL]
# 	11 : GrayLevelNonUniformity [NUMERICAL]
# 	6 : SizeZoneNonUniformityNormalized [NUMERICAL]
# 	3 : SmallAreaEmphasis [NUMERICAL]
# 	2 : ZoneEntropy [NUMERICAL]
# 	1 : SizeZoneNonUniformity [NUMERICAL]
#
# Attribute in nodes with depth <= 1:
# 	246 : HighGrayLevelZoneEmphasis [NUMERICAL]
# 	192 : LowGrayLevelZoneEmphasis [NUMERICAL]
# 	118 : SmallAreaLowGrayLevelEmphasis [NUMERICAL]
# 	114 : SmallAreaHighGrayLevelEmphasis [NUMERICAL]
# 	80 : GrayLevelNonUniformity [NUMERICAL]
# 	60 : LargeAreaHighGrayLevelEmphasis [NUMERICAL]
# 	31 : LargeAreaLowGrayLevelEmphasis [NUMERICAL]
# 	10 : GrayLevelVariance [NUMERICAL]
# 	9 : LargeAreaEmphasis [NUMERICAL]
# 	8 : ZoneEntropy [NUMERICAL]
# 	8 : GrayLevelNonUniformityNormalized [NUMERICAL]
# 	7 : SizeZoneNonUniformityNormalized [NUMERICAL]
# 	6 : SmallAreaEmphasis [NUMERICAL]
# 	6 : SizeZoneNonUniformity [NUMERICAL]
# 	4 : ZoneVariance [NUMERICAL]
# 	1 : ZonePercentage [NUMERICAL]
#
# Attribute in nodes with depth <= 2:
# 	444 : HighGrayLevelZoneEmphasis [NUMERICAL]
# 	328 : LowGrayLevelZoneEmphasis [NUMERICAL]
# 	229 : GrayLevelNonUniformity [NUMERICAL]
# 	222 : SmallAreaHighGrayLevelEmphasis [NUMERICAL]
# 	214 : SmallAreaLowGrayLevelEmphasis [NUMERICAL]
# 	170 : LargeAreaHighGrayLevelEmphasis [NUMERICAL]
# 	88 : LargeAreaLowGrayLevelEmphasis [NUMERICAL]
# 	59 : GrayLevelVariance [NUMERICAL]
# 	56 : ZoneVariance [NUMERICAL]
# 	40 : LargeAreaEmphasis [NUMERICAL]
# 	39 : GrayLevelNonUniformityNormalized [NUMERICAL]
# 	36 : ZoneEntropy [NUMERICAL]
# 	27 : SizeZoneNonUniformity [NUMERICAL]
# 	26 : ZonePercentage [NUMERICAL]
# 	22 : SizeZoneNonUniformityNormalized [NUMERICAL]
# 	20 : SmallAreaEmphasis [NUMERICAL]
#
# Attribute in nodes with depth <= 3:
# 	639 : HighGrayLevelZoneEmphasis [NUMERICAL]
# 	476 : LowGrayLevelZoneEmphasis [NUMERICAL]
# 	470 : GrayLevelNonUniformity [NUMERICAL]
# 	345 : SmallAreaHighGrayLevelEmphasis [NUMERICAL]
# 	344 : LargeAreaHighGrayLevelEmphasis [NUMERICAL]
# 	303 : SmallAreaLowGrayLevelEmphasis [NUMERICAL]
# 	220 : LargeAreaLowGrayLevelEmphasis [NUMERICAL]
# 	173 : GrayLevelVariance [NUMERICAL]
# 	161 : GrayLevelNonUniformityNormalized [NUMERICAL]
# 	147 : ZoneVariance [NUMERICAL]
# 	131 : LargeAreaEmphasis [NUMERICAL]
# 	129 : ZoneEntropy [NUMERICAL]
# 	84 : SizeZoneNonUniformity [NUMERICAL]
# 	75 : SmallAreaEmphasis [NUMERICAL]
# 	73 : ZonePercentage [NUMERICAL]
# 	73 : SizeZoneNonUniformityNormalized [NUMERICAL]
#
# Attribute in nodes with depth <= 5:
# 	1120 : HighGrayLevelZoneEmphasis [NUMERICAL]
# 	1068 : GrayLevelNonUniformity [NUMERICAL]
# 	872 : LargeAreaHighGrayLevelEmphasis [NUMERICAL]
# 	863 : LowGrayLevelZoneEmphasis [NUMERICAL]
# 	670 : SmallAreaHighGrayLevelEmphasis [NUMERICAL]
# 	616 : LargeAreaLowGrayLevelEmphasis [NUMERICAL]
# 	569 : SmallAreaLowGrayLevelEmphasis [NUMERICAL]
# 	508 : GrayLevelNonUniformityNormalized [NUMERICAL]
# 	477 : GrayLevelVariance [NUMERICAL]
# 	447 : ZoneEntropy [NUMERICAL]
# 	436 : ZoneVariance [NUMERICAL]
# 	403 : LargeAreaEmphasis [NUMERICAL]
# 	325 : SmallAreaEmphasis [NUMERICAL]
# 	322 : SizeZoneNonUniformity [NUMERICAL]
# 	319 : SizeZoneNonUniformityNormalized [NUMERICAL]
# 	275 : ZonePercentage [NUMERICAL]
#
# Condition type in nodes:
# 	18001 : HigherCondition
# Condition type in nodes with depth <= 0:
# 	300 : HigherCondition
# Condition type in nodes with depth <= 1:
# 	900 : HigherCondition
# Condition type in nodes with depth <= 2:
# 	2020 : HigherCondition
# Condition type in nodes with depth <= 3:
# 	3843 : HigherCondition
# Condition type in nodes with depth <= 5:
# 	9290 : HigherCondition
# Node format: NOT_SET
#
# Training OOB:
# 	trees: 1, Out-of-bag evaluation: accuracy:0.838172 logloss:5.83286
# 	trees: 11, Out-of-bag evaluation: accuracy:0.862903 logloss:3.83704
# 	trees: 21, Out-of-bag evaluation: accuracy:0.903561 logloss:0.893532
# 	trees: 31, Out-of-bag evaluation: accuracy:0.902252 logloss:0.720036
# 	trees: 41, Out-of-bag evaluation: accuracy:0.902252 logloss:0.500271
# 	trees: 51, Out-of-bag evaluation: accuracy:0.902863 logloss:0.499169
# 	trees: 61, Out-of-bag evaluation: accuracy:0.905074 logloss:0.497691
# 	trees: 71, Out-of-bag evaluation: accuracy:0.907487 logloss:0.491932
# 	trees: 81, Out-of-bag evaluation: accuracy:0.903765 logloss:0.448483
# 	trees: 91, Out-of-bag evaluation: accuracy:0.904054 logloss:0.44801
# 	trees: 101, Out-of-bag evaluation: accuracy:0.902252 logloss:0.403481
# 	trees: 111, Out-of-bag evaluation: accuracy:0.902863 logloss:0.403165
# 	trees: 121, Out-of-bag evaluation: accuracy:0.900943 logloss:0.355087
# 	trees: 131, Out-of-bag evaluation: accuracy:0.903765 logloss:0.354011
# 	trees: 141, Out-of-bag evaluation: accuracy:0.902252 logloss:0.355933
# 	trees: 151, Out-of-bag evaluation: accuracy:0.901147 logloss:0.356788
# 	trees: 161, Out-of-bag evaluation: accuracy:0.897714 logloss:0.35683
# 	trees: 171, Out-of-bag evaluation: accuracy:0.899023 logloss:0.356894
# 	trees: 181, Out-of-bag evaluation: accuracy:0.900739 logloss:0.357649
# 	trees: 191, Out-of-bag evaluation: accuracy:0.901233 logloss:0.316593
# 	trees: 201, Out-of-bag evaluation: accuracy:0.901437 logloss:0.314494
# 	trees: 211, Out-of-bag evaluation: accuracy:0.903153 logloss:0.314531
# 	trees: 221, Out-of-bag evaluation: accuracy:0.900535 logloss:0.313261
# 	trees: 231, Out-of-bag evaluation: accuracy:0.899226 logloss:0.313349
# 	trees: 241, Out-of-bag evaluation: accuracy:0.897306 logloss:0.312066
# 	trees: 251, Out-of-bag evaluation: accuracy:0.902745 logloss:0.310893
# 	trees: 261, Out-of-bag evaluation: accuracy:0.900535 logloss:0.310738
# 	trees: 271, Out-of-bag evaluation: accuracy:0.901844 logloss:0.304957
# 	trees: 281, Out-of-bag evaluation: accuracy:0.900331 logloss:0.303936
# 	trees: 291, Out-of-bag evaluation: accuracy:0.899023 logloss:0.303625
# 	trees: 300, Out-of-bag evaluation: accuracy:0.898819 logloss:0.262491

# %%
# Model features
model.make_inspector().features()
# Out:
# ["GrayLevelNonUniformity" (1; #0),
#  "GrayLevelNonUniformityNormalized" (1; #1),
#  "GrayLevelVariance" (1; #2),
#  "HighGrayLevelZoneEmphasis" (1; #3),
#  "LargeAreaEmphasis" (1; #4),
#  "LargeAreaHighGrayLevelEmphasis" (1; #5),
#  "LargeAreaLowGrayLevelEmphasis" (1; #6),
#  "LowGrayLevelZoneEmphasis" (1; #7),
#  "SizeZoneNonUniformity" (1; #8),
#  "SizeZoneNonUniformityNormalized" (1; #9),
#  "SmallAreaEmphasis" (1; #10),
#  "SmallAreaHighGrayLevelEmphasis" (1; #11),
#  "SmallAreaLowGrayLevelEmphasis" (1; #12),
#  "ZoneEntropy" (1; #13),
#  "ZonePercentage" (1; #14),
#  "ZoneVariance" (1; #15)]

# %%
# Feature importance
model.make_inspector().variable_importances()
# Out:
# {'INV_MEAN_MIN_DEPTH': [("HighGrayLevelZoneEmphasis" (1; #3),
#    0.2620566643212493),
#   ("LowGrayLevelZoneEmphasis" (1; #7), 0.21386971590699413),
#   ("GrayLevelNonUniformity" (1; #0), 0.19410780280397766),
#   ("LargeAreaHighGrayLevelEmphasis" (1; #5), 0.17432056673849333),
#   ("SmallAreaHighGrayLevelEmphasis" (1; #11), 0.1740233586219822),
#   ("SmallAreaLowGrayLevelEmphasis" (1; #12), 0.172194404290301),
#   ("LargeAreaLowGrayLevelEmphasis" (1; #6), 0.15061133829037),
#   ("GrayLevelVariance" (1; #2), 0.13666169685246327),
#   ("ZoneVariance" (1; #15), 0.13601316156404536),
#   ("GrayLevelNonUniformityNormalized" (1; #1), 0.13540515662211045),
#   ("LargeAreaEmphasis" (1; #4), 0.1335746763417397),
#   ("ZoneEntropy" (1; #13), 0.13292273480988234),
#   ("SizeZoneNonUniformity" (1; #8), 0.1300491885094862),
#   ("SizeZoneNonUniformityNormalized" (1; #9), 0.12950345467794372),
#   ("ZonePercentage" (1; #14), 0.1291136464682841),
#   ("SmallAreaEmphasis" (1; #10), 0.12882367045993406)],
#  'NUM_AS_ROOT': [("HighGrayLevelZoneEmphasis" (1; #3), 93.0),
#   ("LowGrayLevelZoneEmphasis" (1; #7), 82.0),
#   ("SmallAreaLowGrayLevelEmphasis" (1; #12), 47.0),
#   ("SmallAreaHighGrayLevelEmphasis" (1; #11), 22.0),
#   ("LargeAreaHighGrayLevelEmphasis" (1; #5), 21.0),
#   ("LargeAreaLowGrayLevelEmphasis" (1; #6), 12.0),
#   ("GrayLevelNonUniformity" (1; #0), 11.0),
#   ("SizeZoneNonUniformityNormalized" (1; #9), 6.0),
#   ("SmallAreaEmphasis" (1; #10), 3.0),
#   ("ZoneEntropy" (1; #13), 2.0),
#   ("SizeZoneNonUniformity" (1; #8), 1.0)],
#  'SUM_SCORE': [("HighGrayLevelZoneEmphasis" (1; #3), 151845.71678922354),
#   ("LowGrayLevelZoneEmphasis" (1; #7), 111650.75226084341),
#   ("SmallAreaLowGrayLevelEmphasis" (1; #12), 68179.17530972067),
#   ("SmallAreaHighGrayLevelEmphasis" (1; #11), 48714.32992098453),
#   ("GrayLevelNonUniformity" (1; #0), 42227.60443337702),
#   ("LargeAreaHighGrayLevelEmphasis" (1; #5), 33008.245688227005),
#   ("LargeAreaLowGrayLevelEmphasis" (1; #6), 20743.085448614554),
#   ("GrayLevelNonUniformityNormalized" (1; #1), 12734.136188265531),
#   ("GrayLevelVariance" (1; #2), 11786.2280671524),
#   ("ZoneVariance" (1; #15), 10255.715950889977),
#   ("ZoneEntropy" (1; #13), 10225.538963457888),
#   ("LargeAreaEmphasis" (1; #4), 8983.12062864664),
#   ("SizeZoneNonUniformity" (1; #8), 7701.565564902887),
#   ("SmallAreaEmphasis" (1; #10), 7428.105759147911),
#   ("SizeZoneNonUniformityNormalized" (1; #9), 6944.802010878658),
#   ("ZonePercentage" (1; #14), 6339.670778938857)],
#  'NUM_NODES': [("GrayLevelNonUniformity" (1; #0), 1809.0),
#   ("HighGrayLevelZoneEmphasis" (1; #3), 1708.0),
#   ("LargeAreaHighGrayLevelEmphasis" (1; #5), 1552.0),
#   ("LowGrayLevelZoneEmphasis" (1; #7), 1470.0),
#   ("LargeAreaLowGrayLevelEmphasis" (1; #6), 1261.0),
#   ("SmallAreaHighGrayLevelEmphasis" (1; #11), 1219.0),
#   ("SmallAreaLowGrayLevelEmphasis" (1; #12), 1092.0),
#   ("GrayLevelNonUniformityNormalized" (1; #1), 1052.0),
#   ("GrayLevelVariance" (1; #2), 986.0),
#   ("ZoneVariance" (1; #15), 962.0),
#   ("ZoneEntropy" (1; #13), 954.0),
#   ("LargeAreaEmphasis" (1; #4), 878.0),
#   ("SmallAreaEmphasis" (1; #10), 811.0),
#   ("SizeZoneNonUniformity" (1; #8), 785.0),
#   ("SizeZoneNonUniformityNormalized" (1; #9), 766.0),
#   ("ZonePercentage" (1; #14), 696.0)]}

# %%
# Model self evaluation
model.make_inspector().evaluation()
# Out:
# Evaluation(num_examples=2835, accuracy=0.8988187334039621, loss=0.2624910325805802, rmse=None, ndcg=None, aucs=None, auuc=None, qini=None)

# %%
logs = model.make_inspector().training_logs()

plt.figure(figsize=(12, 4))
plt.subplot(1, 2, 1)
plt.plot([log.num_trees for log in logs], [log.evaluation.accuracy for log in logs])
plt.xlabel("Number of trees")
plt.ylabel("Accuracy (out-of-bag)")
plt.subplot(1, 2, 2)
plt.plot([log.num_trees for log in logs], [log.evaluation.loss for log in logs])
plt.xlabel("Number of trees")
plt.ylabel("Logloss (out-of-bag)")
plt.show()

# %% [markdown]
# Calculate the score of our hold-out validation dataset

# %%
predictions = model.predict(val_ds)
y_true      = validation_data["label"]

from sklearn.metrics import roc_auc_score
ROC_AUC = roc_auc_score(y_true, predictions)
print("The ROC AUC score is %.5f" % ROC_AUC )
# Out:
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 68ms/step
# The ROC AUC score is 0.98633

# %%
# Compute binary classification metrics with sklearn
import numpy as np
from sklearn.metrics import (
    accuracy_score,
    precision_score,
    recall_score,
    f1_score,
    roc_auc_score,
    average_precision_score,
    confusion_matrix,
    classification_report,
    matthews_corrcoef,
    log_loss,
    brier_score_loss,
)

# Get predictions (probabilities or class labels)
preds = model.predict(test_ds)
# If model outputs probabilities, convert to labels by threshold 0.5
if preds.ndim == 2:
    # For TFDF classification, preds may be class probabilities with shape (N, 2)
    if preds.shape[1] == 2:
        pos_probs = preds[:, 1]
    else:
        # If single-probability column (positive class)
        pos_probs = preds[:, -1]
    y_pred = (pos_probs >= 0.5).astype(int)
else:
    # Already class labels
    y_pred = preds.astype(int)
    pos_probs = None

# Ground truth labels (must be 0/1 integers)
y_true = test_data["label"].astype(int).to_numpy()

# Core metrics
metrics = {}
metrics["accuracy"] = accuracy_score(y_true, y_pred)
metrics["precision"] = precision_score(y_true, y_pred, zero_division=0)
metrics["recall"] = recall_score(y_true, y_pred, zero_division=0)
metrics["f1"] = f1_score(y_true, y_pred, zero_division=0)
metrics["mcc"] = matthews_corrcoef(y_true, y_pred)

# Probabilistic metrics (only if we have probabilities)
if pos_probs is not None:
    metrics["roc_auc"] = roc_auc_score(y_true, pos_probs)
    metrics["pr_auc"] = average_precision_score(y_true, pos_probs)
    metrics["log_loss"] = log_loss(y_true, pos_probs, labels=[0,1])
    metrics["brier_score"] = brier_score_loss(y_true, pos_probs)

# Confusion matrix and detailed report
cm = confusion_matrix(y_true, y_pred, labels=[0,1])
report = classification_report(y_true, y_pred, digits=4)

print("Sklearn binary metrics:")
for k, v in metrics.items():
    print(f"{k}: {v:.4f}")
print("\nConfusion matrix:\n", cm)
print("\nClassification report:\n", report)
# Out:
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 83ms/step
# Sklearn binary metrics:
# accuracy: 0.9531
# precision: 0.8231
# recall: 0.8770
# f1: 0.8492
# mcc: 0.8221
# roc_auc: 0.9826
# pr_auc: 0.9163
# log_loss: 0.1443
# brier_score: 0.0365
#
# Confusion matrix:
#  [[666  23]
#  [ 15 107]]
#
# Classification report:
#                precision    recall  f1-score   support
#
#            0     0.9780    0.9666    0.9723       689
#            1     0.8231    0.8770    0.8492       122
#
#     accuracy                         0.9531       811
#    macro avg     0.9005    0.9218    0.9107       811
# weighted avg     0.9547    0.9531    0.9538       811
