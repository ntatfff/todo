# %%
# Import packages and modules
import numpy  as np
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow_decision_forests as tfdf

from sklearn.model_selection import train_test_split
# Out:
# 2026-08-13 04:22:41.050783: I tensorflow/core/util/port.cc:113] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2026-08-13 04:22:41.438533: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2026-08-13 04:22:46.366786: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
# Check the version of TensorFlow Decision Forests
print("Found TensorFlow Decision Forests v" + tfdf.__version__)
# Out:
# Found TensorFlow Decision Forests v1.9.1

# %%
datasetPath = 'dataset/firstorder/kernel5/dataset.csv'

# %%
# Parameters
datasetPath = "dataset/glcm/kernel3/1.dataset.csv"

# %%
# train/validation/test = 70/10/20
dataset = pd.read_csv(datasetPath)

train_data, temp_data = train_test_split(dataset, test_size=0.3, random_state=42)
validation_data, test_data = train_test_split(temp_data, test_size=2/3, random_state=42)

# %%
from sklearn.utils.class_weight import compute_class_weight

# tinh class weight tren tap train
classes = np.array([0, 1])
weights = compute_class_weight(class_weight="balanced", classes=classes, y=train_data["label"])
class_weight = {0: weights[0], 1: weights[1]}

# gan sample_weight cho tung dong
train_data["sample_weight"] = train_data["label"].map(class_weight)
validation_data["sample_weight"] = validation_data["label"].map(class_weight)
test_data["sample_weight"] = test_data["label"].map(class_weight)

# Convert the dataset into a TensorFlow dataset.
train_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    train_data, label="label", weight="sample_weight"
)         
val_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    validation_data, label="label", weight="sample_weight"
)
test_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    test_data, label="label", weight="sample_weight"
)
# Out:
# 2026-08-13 04:23:00.277551: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:984] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2026-08-13 04:23:00.278698: W tensorflow/core/common_runtime/gpu/gpu_device.cc:2251] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...

# %%
import keras

# %%
# %%time

# Train a Random Forest model.
model = tfdf.keras.RandomForestModel()

# Add evaluation metrics
model.compile(
    metrics=["accuracy"]
)
model.fit(x=train_ds)

# # Train a Gradient Boosted Trees model.
# model = tfdf.keras.GradientBoostedTreesModel(num_trees=1500)
# model.fit(train_ds)
# Out:
# Use /tmp/tmpe028nm0m as temporary training directory
# Reading training dataset...
# Training dataset read in 0:00:02.723384. Found 2835 examples.
# Training model...
# Model trained in 0:00:00.205320
# Compiling model...
# [INFO 26-08-13 04:23:03.3489 UTC kernel.cc:1233] Loading model from path /tmp/tmpe028nm0m/model/ with prefix 072b92ff8ec84ba4
# [INFO 26-08-13 04:23:03.3904 UTC decision_forest.cc:734] Model loaded with 300 root(s), 32388 node(s), and 24 input feature(s).
# [INFO 26-08-13 04:23:03.3904 UTC abstract_model.cc:1362] Engine "RandomForestOptPred" built
# [INFO 26-08-13 04:23:03.3904 UTC kernel.cc:1061] Use fast generic engine
# Model compiled.
# CPU times: user 6.81 s, sys: 110 ms, total: 6.92 s
# Wall time: 6.58 s

# %%
# Evaluate the model
evaluate = model.evaluate(val_ds, return_dict=True)
print()

for name, value in evaluate.items():
    print(f"{name}: {value:.4f}")
# Out:
# WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 1/1 [==============================] - ETA: 0s - loss: 0.0000e+00 - accuracy: 0.9531
# 1/1 [==============================] - 3s 3s/step - loss: 0.0000e+00 - accuracy: 0.9531
# loss: 0.0000
# accuracy: 0.9531

# %%
# Model Summary
model.summary()
# Out:
# Model: "random_forest_model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
# =================================================================
# Total params: 1 (1.00 Byte)
# Trainable params: 0 (0.00 Byte)
# Non-trainable params: 1 (1.00 Byte)
# _________________________________________________________________
# Type: "RANDOM_FOREST"
# Task: CLASSIFICATION
# Label: "__LABEL"
#
# Input Features (24):
# 	Autocorrelation
# 	ClusterProminence
# 	ClusterShade
# 	ClusterTendency
# 	Contrast
# 	Correlation
# 	DifferenceAverage
# 	DifferenceEntropy
# 	DifferenceVariance
# 	Id
# 	Idm
# 	Idmn
# 	Idn
# 	Imc1
# 	Imc2
# 	InverseVariance
# 	JointAverage
# 	JointEnergy
# 	JointEntropy
# 	MCC
# 	MaximumProbability
# 	SumAverage
# 	SumEntropy
# 	SumSquares
#
# Trained with weights
#
# Variable Importance: INV_MEAN_MIN_DEPTH:
#     1.    "Autocorrelation"  0.225624 ################
#     2.         "SumAverage"  0.217151 ##############
#     3.       "JointAverage"  0.196140 ###########
#     4.        "Correlation"  0.158397 ####
#     5.    "InverseVariance"  0.153859 ####
#     6. "DifferenceVariance"  0.145943 ##
#     7.                "Idm"  0.143282 ##
#     8. "MaximumProbability"  0.142223 ##
#     9.                 "Id"  0.141464 ##
#    10.        "JointEnergy"  0.139066 #
#    11.                "MCC"  0.139014 #
#    12.               "Imc2"  0.138123 #
#    13.  "DifferenceEntropy"  0.137974 #
#    14.         "SumEntropy"  0.136863 #
#    15.               "Idmn"  0.136583 #
#    16.               "Imc1"  0.136229 #
#    17.           "Contrast"  0.132668
#    18.       "ClusterShade"  0.132440
#    19.       "JointEntropy"  0.131473
#    20.  "DifferenceAverage"  0.130996
#    21.  "ClusterProminence"  0.129888
#    22.                "Idn"  0.129649
#    23.    "ClusterTendency"  0.128074
#    24.         "SumSquares"  0.128064
#
# Variable Importance: NUM_AS_ROOT:
#     1.    "Autocorrelation" 67.000000 ################
#     2.         "SumAverage" 66.000000 ###############
#     3.       "JointAverage" 42.000000 #########
#     4. "DifferenceVariance" 37.000000 ########
#     5.    "InverseVariance" 22.000000 #####
#     6.               "Idmn" 14.000000 ###
#     7.           "Contrast" 11.000000 ##
#     8.        "Correlation" 11.000000 ##
#     9.  "DifferenceEntropy" 10.000000 ##
#    10. "MaximumProbability" 10.000000 ##
#    11.  "DifferenceAverage"  4.000000
#    12.        "JointEnergy"  3.000000
#    13.               "Imc2"  2.000000
#    14.                "MCC"  1.000000
#
# Variable Importance: NUM_NODES:
#     1.    "Autocorrelation" 1259.000000 ################
#     2.         "SumAverage" 1146.000000 #############
#     3.       "JointAverage" 1057.000000 ############
#     4.        "Correlation" 947.000000 ##########
#     5.       "ClusterShade" 796.000000 #######
#     6.                "MCC" 789.000000 #######
#     7. "MaximumProbability" 765.000000 ######
#     8.               "Imc1" 737.000000 ######
#     9.    "InverseVariance" 698.000000 #####
#    10.               "Imc2" 680.000000 #####
#    11.                "Idm" 673.000000 #####
#    12.        "JointEnergy" 662.000000 #####
#    13.                 "Id" 659.000000 #####
#    14. "DifferenceVariance" 572.000000 ###
#    15.         "SumEntropy" 563.000000 ###
#    16.  "ClusterProminence" 556.000000 ###
#    17.       "JointEntropy" 521.000000 ##
#    18.  "DifferenceEntropy" 494.000000 ##
#    19.               "Idmn" 450.000000 #
#    20.           "Contrast" 426.000000
#    21.                "Idn" 414.000000
#    22.    "ClusterTendency" 406.000000
#    23.         "SumSquares" 392.000000
#    24.  "DifferenceAverage" 382.000000
#
# Variable Importance: SUM_SCORE:
#     1.    "Autocorrelation" 146475.555267 ################
#     2.         "SumAverage" 137859.111066 ###############
#     3.       "JointAverage" 104541.617590 ###########
#     4.        "Correlation" 16804.509951 #
#     5.    "InverseVariance" 12734.085266 #
#     6.                "Idm" 12515.506582
#     7.                 "Id" 11368.804803
#     8. "MaximumProbability" 10612.971541
#     9. "DifferenceVariance" 10041.355064
#    10.               "Imc2" 9978.641433
#    11.                "MCC" 9342.269589
#    12.        "JointEnergy" 9201.098759
#    13.               "Imc1" 8968.302431
#    14.         "SumEntropy" 8404.139521
#    15.       "ClusterShade" 7372.584338
#    16.  "DifferenceEntropy" 7056.663071
#    17.       "JointEntropy" 6156.031340
#    18.               "Idmn" 5856.799002
#    19.  "ClusterProminence" 5486.680603
#    20.           "Contrast" 4896.706523
#    21.  "DifferenceAverage" 4214.720384
#    22.    "ClusterTendency" 4104.619545
#    23.                "Idn" 4096.621013
#    24.         "SumSquares" 3665.083165
#
#
#
# Winner takes all: true
# Out-of-bag evaluation: accuracy:0.922669 logloss:0.234383
# Number of trees: 300
# Total number of nodes: 32388
#
# Number of nodes by tree:
# Count: 300 Average: 107.96 StdDev: 9.98057
# Min: 81 Max: 141 Ignored: 0
# ----------------------------------------------
# [  81,  84)  1   0.33%   0.33%
# [  84,  87)  1   0.33%   0.67%
# [  87,  90)  3   1.00%   1.67% #
# [  90,  93)  5   1.67%   3.33% #
# [  93,  96) 26   8.67%  12.00% #####
# [  96,  99) 11   3.67%  15.67% ##
# [  99, 102) 38  12.67%  28.33% #######
# [ 102, 105) 25   8.33%  36.67% #####
# [ 105, 108) 43  14.33%  51.00% ########
# [ 108, 111) 23   7.67%  58.67% ####
# [ 111, 114) 52  17.33%  76.00% ##########
# [ 114, 117) 16   5.33%  81.33% ###
# [ 117, 120) 23   7.67%  89.00% ####
# [ 120, 123) 10   3.33%  92.33% ##
# [ 123, 126) 12   4.00%  96.33% ##
# [ 126, 129)  2   0.67%  97.00%
# [ 129, 132)  2   0.67%  97.67%
# [ 132, 135)  0   0.00%  97.67%
# [ 135, 138)  4   1.33%  99.00% #
# [ 138, 141]  3   1.00% 100.00% #
#
# Depth by leafs:
# Count: 16344 Average: 7.14593 StdDev: 2.16804
# Min: 1 Max: 15 Ignored: 0
# ----------------------------------------------
# [  1,  2)    5   0.03%   0.03%
# [  2,  3)   94   0.58%   0.61%
# [  3,  4)  410   2.51%   3.11% #
# [  4,  5) 1171   7.16%  10.28% ####
# [  5,  6) 2174  13.30%  23.58% #######
# [  6,  7) 2792  17.08%  40.66% ##########
# [  7,  8) 2904  17.77%  58.43% ##########
# [  8,  9) 2544  15.57%  74.00% #########
# [  9, 10) 1946  11.91%  85.90% #######
# [ 10, 11) 1215   7.43%  93.34% ####
# [ 11, 12)  610   3.73%  97.07% ##
# [ 12, 13)  290   1.77%  98.84% #
# [ 13, 14)  130   0.80%  99.64%
# [ 14, 15)   45   0.28%  99.91%
# [ 15, 15]   14   0.09% 100.00%
#
# Number of training obs by leaf:
# Count: 16344 Average: 52.0374 StdDev: 152.933
# Min: 5 Max: 1762 Ignored: 0
# ----------------------------------------------
# [    5,   92) 14573  89.16%  89.16% ##########
# [   92,  180)   745   4.56%  93.72% #
# [  180,  268)   290   1.77%  95.50%
# [  268,  356)   139   0.85%  96.35%
# [  356,  444)   105   0.64%  96.99%
# [  444,  532)    86   0.53%  97.52%
# [  532,  620)    75   0.46%  97.97%
# [  620,  708)    75   0.46%  98.43%
# [  708,  796)    43   0.26%  98.70%
# [  796,  884)    42   0.26%  98.95%
# [  884,  971)    27   0.17%  99.12%
# [  971, 1059)    37   0.23%  99.35%
# [ 1059, 1147)    30   0.18%  99.53%
# [ 1147, 1235)    29   0.18%  99.71%
# [ 1235, 1323)    15   0.09%  99.80%
# [ 1323, 1411)    18   0.11%  99.91%
# [ 1411, 1499)     8   0.05%  99.96%
# [ 1499, 1587)     4   0.02%  99.98%
# [ 1587, 1675)     2   0.01%  99.99%
# [ 1675, 1762]     1   0.01% 100.00%
#
# Attribute in nodes:
# 	1259 : Autocorrelation [NUMERICAL]
# 	1146 : SumAverage [NUMERICAL]
# 	1057 : JointAverage [NUMERICAL]
# 	947 : Correlation [NUMERICAL]
# 	796 : ClusterShade [NUMERICAL]
# 	789 : MCC [NUMERICAL]
# 	765 : MaximumProbability [NUMERICAL]
# 	737 : Imc1 [NUMERICAL]
# 	698 : InverseVariance [NUMERICAL]
# 	680 : Imc2 [NUMERICAL]
# 	673 : Idm [NUMERICAL]
# 	662 : JointEnergy [NUMERICAL]
# 	659 : Id [NUMERICAL]
# 	572 : DifferenceVariance [NUMERICAL]
# 	563 : SumEntropy [NUMERICAL]
# 	556 : ClusterProminence [NUMERICAL]
# 	521 : JointEntropy [NUMERICAL]
# 	494 : DifferenceEntropy [NUMERICAL]
# 	450 : Idmn [NUMERICAL]
# 	426 : Contrast [NUMERICAL]
# 	414 : Idn [NUMERICAL]
# 	406 : ClusterTendency [NUMERICAL]
# 	392 : SumSquares [NUMERICAL]
# 	382 : DifferenceAverage [NUMERICAL]
#
# Attribute in nodes with depth <= 0:
# 	67 : Autocorrelation [NUMERICAL]
# 	66 : SumAverage [NUMERICAL]
# 	42 : JointAverage [NUMERICAL]
# 	37 : DifferenceVariance [NUMERICAL]
# 	22 : InverseVariance [NUMERICAL]
# 	14 : Idmn [NUMERICAL]
# 	11 : Correlation [NUMERICAL]
# 	11 : Contrast [NUMERICAL]
# 	10 : MaximumProbability [NUMERICAL]
# 	10 : DifferenceEntropy [NUMERICAL]
# 	4 : DifferenceAverage [NUMERICAL]
# 	3 : JointEnergy [NUMERICAL]
# 	2 : Imc2 [NUMERICAL]
# 	1 : MCC [NUMERICAL]
#
# Attribute in nodes with depth <= 1:
# 	184 : Autocorrelation [NUMERICAL]
# 	182 : SumAverage [NUMERICAL]
# 	147 : JointAverage [NUMERICAL]
# 	56 : Correlation [NUMERICAL]
# 	49 : InverseVariance [NUMERICAL]
# 	42 : DifferenceVariance [NUMERICAL]
# 	33 : SumEntropy [NUMERICAL]
# 	33 : Imc2 [NUMERICAL]
# 	20 : Idmn [NUMERICAL]
# 	20 : DifferenceEntropy [NUMERICAL]
# 	17 : MaximumProbability [NUMERICAL]
# 	16 : Contrast [NUMERICAL]
# 	15 : MCC [NUMERICAL]
# 	15 : Idm [NUMERICAL]
# 	15 : Id [NUMERICAL]
# 	11 : JointEnergy [NUMERICAL]
# 	10 : Imc1 [NUMERICAL]
# 	8 : Idn [NUMERICAL]
# 	8 : DifferenceAverage [NUMERICAL]
# 	5 : ClusterShade [NUMERICAL]
# 	4 : JointEntropy [NUMERICAL]
# 	2 : SumSquares [NUMERICAL]
# 	2 : ClusterTendency [NUMERICAL]
# 	1 : ClusterProminence [NUMERICAL]
#
# Attribute in nodes with depth <= 2:
# 	328 : Autocorrelation [NUMERICAL]
# 	308 : SumAverage [NUMERICAL]
# 	264 : JointAverage [NUMERICAL]
# 	115 : Correlation [NUMERICAL]
# 	100 : InverseVariance [NUMERICAL]
# 	79 : Imc2 [NUMERICAL]
# 	77 : Idm [NUMERICAL]
# 	73 : DifferenceVariance [NUMERICAL]
# 	72 : SumEntropy [NUMERICAL]
# 	71 : Id [NUMERICAL]
# 	69 : MaximumProbability [NUMERICAL]
# 	60 : JointEnergy [NUMERICAL]
# 	50 : MCC [NUMERICAL]
# 	43 : JointEntropy [NUMERICAL]
# 	42 : DifferenceEntropy [NUMERICAL]
# 	41 : Imc1 [NUMERICAL]
# 	35 : Idmn [NUMERICAL]
# 	33 : ClusterShade [NUMERICAL]
# 	24 : ClusterTendency [NUMERICAL]
# 	24 : ClusterProminence [NUMERICAL]
# 	22 : Contrast [NUMERICAL]
# 	21 : Idn [NUMERICAL]
# 	21 : DifferenceAverage [NUMERICAL]
# 	19 : SumSquares [NUMERICAL]
#
# Attribute in nodes with depth <= 3:
# 	500 : Autocorrelation [NUMERICAL]
# 	442 : SumAverage [NUMERICAL]
# 	401 : JointAverage [NUMERICAL]
# 	217 : Correlation [NUMERICAL]
# 	193 : InverseVariance [NUMERICAL]
# 	170 : Id [NUMERICAL]
# 	163 : Idm [NUMERICAL]
# 	159 : MaximumProbability [NUMERICAL]
# 	145 : JointEnergy [NUMERICAL]
# 	136 : Imc2 [NUMERICAL]
# 	135 : SumEntropy [NUMERICAL]
# 	132 : MCC [NUMERICAL]
# 	124 : Imc1 [NUMERICAL]
# 	121 : DifferenceVariance [NUMERICAL]
# 	106 : JointEntropy [NUMERICAL]
# 	100 : ClusterShade [NUMERICAL]
# 	85 : Idmn [NUMERICAL]
# 	80 : DifferenceEntropy [NUMERICAL]
# 	70 : ClusterProminence [NUMERICAL]
# 	63 : Contrast [NUMERICAL]
# 	62 : DifferenceAverage [NUMERICAL]
# 	60 : ClusterTendency [NUMERICAL]
# 	55 : Idn [NUMERICAL]
# 	54 : SumSquares [NUMERICAL]
#
# Attribute in nodes with depth <= 5:
# 	848 : Autocorrelation [NUMERICAL]
# 	778 : SumAverage [NUMERICAL]
# 	723 : JointAverage [NUMERICAL]
# 	551 : Correlation [NUMERICAL]
# 	418 : MaximumProbability [NUMERICAL]
# 	408 : InverseVariance [NUMERICAL]
# 	383 : Idm [NUMERICAL]
# 	377 : MCC [NUMERICAL]
# 	377 : Id [NUMERICAL]
# 	365 : JointEnergy [NUMERICAL]
# 	365 : Imc1 [NUMERICAL]
# 	362 : ClusterShade [NUMERICAL]
# 	348 : Imc2 [NUMERICAL]
# 	301 : SumEntropy [NUMERICAL]
# 	288 : DifferenceVariance [NUMERICAL]
# 	269 : JointEntropy [NUMERICAL]
# 	252 : ClusterProminence [NUMERICAL]
# 	231 : DifferenceEntropy [NUMERICAL]
# 	219 : Idmn [NUMERICAL]
# 	189 : ClusterTendency [NUMERICAL]
# 	188 : Contrast [NUMERICAL]
# 	187 : DifferenceAverage [NUMERICAL]
# 	184 : Idn [NUMERICAL]
# 	167 : SumSquares [NUMERICAL]
#
# Condition type in nodes:
# 	16044 : HigherCondition
# Condition type in nodes with depth <= 0:
# 	300 : HigherCondition
# Condition type in nodes with depth <= 1:
# 	895 : HigherCondition
# Condition type in nodes with depth <= 2:
# 	1991 : HigherCondition
# Condition type in nodes with depth <= 3:
# 	3773 : HigherCondition
# Condition type in nodes with depth <= 5:
# 	8778 : HigherCondition
# Node format: NOT_SET
#
# Training OOB:
# 	trees: 1, Out-of-bag evaluation: accuracy:0.903468 logloss:3.47938
# 	trees: 12, Out-of-bag evaluation: accuracy:0.905752 logloss:2.1166
# 	trees: 22, Out-of-bag evaluation: accuracy:0.916291 logloss:0.768138
# 	trees: 32, Out-of-bag evaluation: accuracy:0.917819 logloss:0.659383
# 	trees: 42, Out-of-bag evaluation: accuracy:0.920937 logloss:0.543815
# 	trees: 52, Out-of-bag evaluation: accuracy:0.923283 logloss:0.538146
# 	trees: 62, Out-of-bag evaluation: accuracy:0.923692 logloss:0.539547
# 	trees: 72, Out-of-bag evaluation: accuracy:0.922008 logloss:0.531693
# 	trees: 82, Out-of-bag evaluation: accuracy:0.922417 logloss:0.48821
# 	trees: 92, Out-of-bag evaluation: accuracy:0.921803 logloss:0.447307
# 	trees: 102, Out-of-bag evaluation: accuracy:0.923078 logloss:0.440967
# 	trees: 112, Out-of-bag evaluation: accuracy:0.922464 logloss:0.40085
# 	trees: 122, Out-of-bag evaluation: accuracy:0.922669 logloss:0.361757
# 	trees: 132, Out-of-bag evaluation: accuracy:0.92522 logloss:0.362593
# 	trees: 142, Out-of-bag evaluation: accuracy:0.922464 logloss:0.362469
# 	trees: 152, Out-of-bag evaluation: accuracy:0.922464 logloss:0.361969
# 	trees: 162, Out-of-bag evaluation: accuracy:0.923945 logloss:0.362186
# 	trees: 172, Out-of-bag evaluation: accuracy:0.921189 logloss:0.363309
# 	trees: 183, Out-of-bag evaluation: accuracy:0.923078 logloss:0.32182
# 	trees: 193, Out-of-bag evaluation: accuracy:0.92374 logloss:0.321599
# 	trees: 203, Out-of-bag evaluation: accuracy:0.92374 logloss:0.321481
# 	trees: 213, Out-of-bag evaluation: accuracy:0.922464 logloss:0.321174
# 	trees: 223, Out-of-bag evaluation: accuracy:0.925834 logloss:0.281943
# 	trees: 233, Out-of-bag evaluation: accuracy:0.922874 logloss:0.280738
# 	trees: 244, Out-of-bag evaluation: accuracy:0.924559 logloss:0.280625
# 	trees: 254, Out-of-bag evaluation: accuracy:0.924354 logloss:0.234928
# 	trees: 264, Out-of-bag evaluation: accuracy:0.924149 logloss:0.235548
# 	trees: 274, Out-of-bag evaluation: accuracy:0.924606 logloss:0.235033
# 	trees: 284, Out-of-bag evaluation: accuracy:0.921394 logloss:0.234962
# 	trees: 294, Out-of-bag evaluation: accuracy:0.92374 logloss:0.234743
# 	trees: 300, Out-of-bag evaluation: accuracy:0.922669 logloss:0.234383

# %%
# Model features
model.make_inspector().features()
# Out:
# ["Autocorrelation" (1; #0),
#  "ClusterProminence" (1; #1),
#  "ClusterShade" (1; #2),
#  "ClusterTendency" (1; #3),
#  "Contrast" (1; #4),
#  "Correlation" (1; #5),
#  "DifferenceAverage" (1; #6),
#  "DifferenceEntropy" (1; #7),
#  "DifferenceVariance" (1; #8),
#  "Id" (1; #9),
#  "Idm" (1; #10),
#  "Idmn" (1; #11),
#  "Idn" (1; #12),
#  "Imc1" (1; #13),
#  "Imc2" (1; #14),
#  "InverseVariance" (1; #15),
#  "JointAverage" (1; #16),
#  "JointEnergy" (1; #17),
#  "JointEntropy" (1; #18),
#  "MCC" (1; #19),
#  "MaximumProbability" (1; #20),
#  "SumAverage" (1; #21),
#  "SumEntropy" (1; #22),
#  "SumSquares" (1; #23)]

# %%
# Feature importance
model.make_inspector().variable_importances()
# Out:
# {'INV_MEAN_MIN_DEPTH': [("Autocorrelation" (1; #0), 0.22562353815240757),
#   ("SumAverage" (1; #21), 0.2171511289357009),
#   ("JointAverage" (1; #16), 0.19613989156275416),
#   ("Correlation" (1; #5), 0.1583968783775754),
#   ("InverseVariance" (1; #15), 0.1538590530611354),
#   ("DifferenceVariance" (1; #8), 0.14594270107094012),
#   ("Idm" (1; #10), 0.14328195793156276),
#   ("MaximumProbability" (1; #20), 0.14222292037291756),
#   ("Id" (1; #9), 0.14146369712418763),
#   ("JointEnergy" (1; #17), 0.1390664464895601),
#   ("MCC" (1; #19), 0.1390141978579063),
#   ("Imc2" (1; #14), 0.13812341173750017),
#   ("DifferenceEntropy" (1; #7), 0.13797420878418906),
#   ("SumEntropy" (1; #22), 0.1368633322185245),
#   ("Idmn" (1; #11), 0.13658289623060066),
#   ("Imc1" (1; #13), 0.13622887216671525),
#   ("Contrast" (1; #4), 0.13266794750309788),
#   ("ClusterShade" (1; #2), 0.13244038197435454),
#   ("JointEntropy" (1; #18), 0.13147279403798792),
#   ("DifferenceAverage" (1; #6), 0.13099596074956119),
#   ("ClusterProminence" (1; #1), 0.12988836150306923),
#   ("Idn" (1; #12), 0.12964877829192845),
#   ("ClusterTendency" (1; #3), 0.1280743358881554),
#   ("SumSquares" (1; #23), 0.1280637623279922)],
#  'SUM_SCORE': [("Autocorrelation" (1; #0), 146475.55526710674),
#   ("SumAverage" (1; #21), 137859.1110656279),
#   ("JointAverage" (1; #16), 104541.6175902793),
#   ("Correlation" (1; #5), 16804.509950936845),
#   ("InverseVariance" (1; #15), 12734.085265882917),
#   ("Idm" (1; #10), 12515.506582487676),
#   ("Id" (1; #9), 11368.80480253544),
#   ("MaximumProbability" (1; #20), 10612.971541443769),
#   ("DifferenceVariance" (1; #8), 10041.35506418802),
#   ("Imc2" (1; #14), 9978.641432919836),
#   ("MCC" (1; #19), 9342.269588833899),
#   ("JointEnergy" (1; #17), 9201.098759423594),
#   ("Imc1" (1; #13), 8968.302430972903),
#   ("SumEntropy" (1; #22), 8404.139520860497),
#   ("ClusterShade" (1; #2), 7372.584337713521),
#   ("DifferenceEntropy" (1; #7), 7056.663070748408),
#   ("JointEntropy" (1; #18), 6156.0313399714305),
#   ("Idmn" (1; #11), 5856.799001551999),
#   ("ClusterProminence" (1; #1), 5486.680603361904),
#   ("Contrast" (1; #4), 4896.70652298572),
#   ("DifferenceAverage" (1; #6), 4214.720383539076),
#   ("ClusterTendency" (1; #3), 4104.619545481123),
#   ("Idn" (1; #12), 4096.621013303199),
#   ("SumSquares" (1; #23), 3665.083164710176)],
#  'NUM_AS_ROOT': [("Autocorrelation" (1; #0), 67.0),
#   ("SumAverage" (1; #21), 66.0),
#   ("JointAverage" (1; #16), 42.0),
#   ("DifferenceVariance" (1; #8), 37.0),
#   ("InverseVariance" (1; #15), 22.0),
#   ("Idmn" (1; #11), 14.0),
#   ("Contrast" (1; #4), 11.0),
#   ("Correlation" (1; #5), 11.0),
#   ("DifferenceEntropy" (1; #7), 10.0),
#   ("MaximumProbability" (1; #20), 10.0),
#   ("DifferenceAverage" (1; #6), 4.0),
#   ("JointEnergy" (1; #17), 3.0),
#   ("Imc2" (1; #14), 2.0),
#   ("MCC" (1; #19), 1.0)],
#  'NUM_NODES': [("Autocorrelation" (1; #0), 1259.0),
#   ("SumAverage" (1; #21), 1146.0),
#   ("JointAverage" (1; #16), 1057.0),
#   ("Correlation" (1; #5), 947.0),
#   ("ClusterShade" (1; #2), 796.0),
#   ("MCC" (1; #19), 789.0),
#   ("MaximumProbability" (1; #20), 765.0),
#   ("Imc1" (1; #13), 737.0),
#   ("InverseVariance" (1; #15), 698.0),
#   ("Imc2" (1; #14), 680.0),
#   ("Idm" (1; #10), 673.0),
#   ("JointEnergy" (1; #17), 662.0),
#   ("Id" (1; #9), 659.0),
#   ("DifferenceVariance" (1; #8), 572.0),
#   ("SumEntropy" (1; #22), 563.0),
#   ("ClusterProminence" (1; #1), 556.0),
#   ("JointEntropy" (1; #18), 521.0),
#   ("DifferenceEntropy" (1; #7), 494.0),
#   ("Idmn" (1; #11), 450.0),
#   ("Contrast" (1; #4), 426.0),
#   ("Idn" (1; #12), 414.0),
#   ("ClusterTendency" (1; #3), 406.0),
#   ("SumSquares" (1; #23), 392.0),
#   ("DifferenceAverage" (1; #6), 382.0)]}

# %%
# Model self evaluation
model.make_inspector().evaluation()
# Out:
# Evaluation(num_examples=2835, accuracy=0.9226689955535281, loss=0.23438321276249552, rmse=None, ndcg=None, aucs=None, auuc=None, qini=None)

# %%
logs = model.make_inspector().training_logs()

plt.figure(figsize=(12, 4))
plt.subplot(1, 2, 1)
plt.plot([log.num_trees for log in logs], [log.evaluation.accuracy for log in logs])
plt.xlabel("Number of trees")
plt.ylabel("Accuracy (out-of-bag)")
plt.subplot(1, 2, 2)
plt.plot([log.num_trees for log in logs], [log.evaluation.loss for log in logs])
plt.xlabel("Number of trees")
plt.ylabel("Logloss (out-of-bag)")
plt.show()

# %% [markdown]
# Calculate the score of our hold-out validation dataset

# %%
predictions = model.predict(val_ds)
y_true      = validation_data["label"]

from sklearn.metrics import roc_auc_score
ROC_AUC = roc_auc_score(y_true, predictions)
print("The ROC AUC score is %.5f" % ROC_AUC )
# Out:
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 77ms/step
# The ROC AUC score is 0.96527

# %%
# Compute binary classification metrics with sklearn
import numpy as np
from sklearn.metrics import (
    accuracy_score,
    precision_score,
    recall_score,
    f1_score,
    roc_auc_score,
    average_precision_score,
    confusion_matrix,
    classification_report,
    matthews_corrcoef,
    log_loss,
    brier_score_loss,
)

# Get predictions (probabilities or class labels)
preds = model.predict(test_ds)
# If model outputs probabilities, convert to labels by threshold 0.5
if preds.ndim == 2:
    # For TFDF classification, preds may be class probabilities with shape (N, 2)
    if preds.shape[1] == 2:
        pos_probs = preds[:, 1]
    else:
        # If single-probability column (positive class)
        pos_probs = preds[:, -1]
    y_pred = (pos_probs >= 0.5).astype(int)
else:
    # Already class labels
    y_pred = preds.astype(int)
    pos_probs = None

# Ground truth labels (must be 0/1 integers)
y_true = test_data["label"].astype(int).to_numpy()

# Core metrics
metrics = {}
metrics["accuracy"] = accuracy_score(y_true, y_pred)
metrics["precision"] = precision_score(y_true, y_pred, zero_division=0)
metrics["recall"] = recall_score(y_true, y_pred, zero_division=0)
metrics["f1"] = f1_score(y_true, y_pred, zero_division=0)
metrics["mcc"] = matthews_corrcoef(y_true, y_pred)

# Probabilistic metrics (only if we have probabilities)
if pos_probs is not None:
    metrics["roc_auc"] = roc_auc_score(y_true, pos_probs)
    metrics["pr_auc"] = average_precision_score(y_true, pos_probs)
    metrics["log_loss"] = log_loss(y_true, pos_probs, labels=[0,1])
    metrics["brier_score"] = brier_score_loss(y_true, pos_probs)

# Confusion matrix and detailed report
cm = confusion_matrix(y_true, y_pred, labels=[0,1])
report = classification_report(y_true, y_pred, digits=4)

print("Sklearn binary metrics:")
for k, v in metrics.items():
    print(f"{k}: {v:.4f}")
print("\nConfusion matrix:\n", cm)
print("\nClassification report:\n", report)
# Out:
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 81ms/step
# Sklearn binary metrics:
# accuracy: 0.9679
# precision: 0.8583
# recall: 0.9196
# f1: 0.8879
# mcc: 0.8700
# roc_auc: 0.9918
# pr_auc: 0.9544
# log_loss: 0.0941
# brier_score: 0.0229
#
# Confusion matrix:
#  [[682  17]
#  [  9 103]]
#
# Classification report:
#                precision    recall  f1-score   support
#
#            0     0.9870    0.9757    0.9813       699
#            1     0.8583    0.9196    0.8879       112
#
#     accuracy                         0.9679       811
#    macro avg     0.9227    0.9477    0.9346       811
# weighted avg     0.9692    0.9679    0.9684       811
