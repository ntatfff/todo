# %%
# Import packages and modules
import numpy  as np
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow_decision_forests as tfdf

from sklearn.model_selection import train_test_split
# Out:
# 2026-08-13 04:23:18.988675: I tensorflow/core/util/port.cc:113] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2026-08-13 04:23:19.421706: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2026-08-13 04:23:24.398225: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
# Check the version of TensorFlow Decision Forests
print("Found TensorFlow Decision Forests v" + tfdf.__version__)
# Out:
# Found TensorFlow Decision Forests v1.9.1

# %%
datasetPath = 'dataset/firstorder/kernel5/dataset.csv'

# %%
# Parameters
datasetPath = "dataset/gldm/kernel3/1.dataset.csv"

# %%
# train/validation/test = 70/10/20
dataset = pd.read_csv(datasetPath)

train_data, temp_data = train_test_split(dataset, test_size=0.3, random_state=42)
validation_data, test_data = train_test_split(temp_data, test_size=2/3, random_state=42)

# %%
from sklearn.utils.class_weight import compute_class_weight

# tinh class weight tren tap train
classes = np.array([0, 1])
weights = compute_class_weight(class_weight="balanced", classes=classes, y=train_data["label"])
class_weight = {0: weights[0], 1: weights[1]}

# gan sample_weight cho tung dong
train_data["sample_weight"] = train_data["label"].map(class_weight)
validation_data["sample_weight"] = validation_data["label"].map(class_weight)
test_data["sample_weight"] = test_data["label"].map(class_weight)

# Convert the dataset into a TensorFlow dataset.
train_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    train_data, label="label", weight="sample_weight"
)         
val_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    validation_data, label="label", weight="sample_weight"
)
test_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    test_data, label="label", weight="sample_weight"
)
# Out:
# 2026-08-13 04:23:38.443934: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:984] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2026-08-13 04:23:38.445611: W tensorflow/core/common_runtime/gpu/gpu_device.cc:2251] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...

# %%
import keras

# %%
# %%time

# Train a Random Forest model.
model = tfdf.keras.RandomForestModel()

# Add evaluation metrics
model.compile(
    metrics=["accuracy"]
)
model.fit(x=train_ds)

# # Train a Gradient Boosted Trees model.
# model = tfdf.keras.GradientBoostedTreesModel(num_trees=1500)
# model.fit(train_ds)
# Out:
# Use /tmp/tmp38am9jwj as temporary training directory
# Reading training dataset...
# Training dataset read in 0:00:02.718662. Found 2835 examples.
# Training model...
# Model trained in 0:00:00.189108
# Compiling model...
# [INFO 26-08-13 04:23:41.4797 UTC kernel.cc:1233] Loading model from path /tmp/tmp38am9jwj/model/ with prefix fd1a2449d6564406
# [INFO 26-08-13 04:23:41.5242 UTC decision_forest.cc:734] Model loaded with 300 root(s), 31266 node(s), and 14 input feature(s).
# [INFO 26-08-13 04:23:41.5242 UTC abstract_model.cc:1362] Engine "RandomForestOptPred" built
# [INFO 26-08-13 04:23:41.5242 UTC kernel.cc:1061] Use fast generic engine
# Model compiled.
# CPU times: user 6.6 s, sys: 120 ms, total: 6.72 s
# Wall time: 6.18 s

# %%
# Evaluate the model
evaluate = model.evaluate(val_ds, return_dict=True)
print()

for name, value in evaluate.items():
    print(f"{name}: {value:.4f}")
# Out:
# WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 1/1 [==============================] - ETA: 0s - loss: 0.0000e+00 - accuracy: 0.9753
# 1/1 [==============================] - 3s 3s/step - loss: 0.0000e+00 - accuracy: 0.9753
# loss: 0.0000
# accuracy: 0.9753

# %%
# Model Summary
model.summary()
# Out:
# Model: "random_forest_model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
# =================================================================
# Total params: 1 (1.00 Byte)
# Trainable params: 0 (0.00 Byte)
# Non-trainable params: 1 (1.00 Byte)
# _________________________________________________________________
# Type: "RANDOM_FOREST"
# Task: CLASSIFICATION
# Label: "__LABEL"
#
# Input Features (14):
# 	DependenceEntropy
# 	DependenceNonUniformity
# 	DependenceNonUniformityNormalized
# 	DependenceVariance
# 	GrayLevelNonUniformity
# 	GrayLevelVariance
# 	HighGrayLevelEmphasis
# 	LargeDependenceEmphasis
# 	LargeDependenceHighGrayLevelEmphasis
# 	LargeDependenceLowGrayLevelEmphasis
# 	LowGrayLevelEmphasis
# 	SmallDependenceEmphasis
# 	SmallDependenceHighGrayLevelEmphasis
# 	SmallDependenceLowGrayLevelEmphasis
#
# Trained with weights
#
# Variable Importance: INV_MEAN_MIN_DEPTH:
#     1.                "HighGrayLevelEmphasis"  0.317450 ################
#     2.                 "LowGrayLevelEmphasis"  0.234002 ########
#     3. "LargeDependenceHighGrayLevelEmphasis"  0.230941 ########
#     4.  "SmallDependenceLowGrayLevelEmphasis"  0.171362 ##
#     5.                    "DependenceEntropy"  0.156178 #
#     6. "SmallDependenceHighGrayLevelEmphasis"  0.153622 #
#     7.  "LargeDependenceLowGrayLevelEmphasis"  0.149709
#     8.                    "GrayLevelVariance"  0.145347
#     9.               "GrayLevelNonUniformity"  0.144756
#    10.              "LargeDependenceEmphasis"  0.144322
#    11.                   "DependenceVariance"  0.143960
#    12.              "SmallDependenceEmphasis"  0.142474
#    13.              "DependenceNonUniformity"  0.140059
#    14.    "DependenceNonUniformityNormalized"  0.139835
#
# Variable Importance: NUM_AS_ROOT:
#     1.                "HighGrayLevelEmphasis" 105.000000 ################
#     2.                 "LowGrayLevelEmphasis" 85.000000 ############
#     3. "LargeDependenceHighGrayLevelEmphasis" 48.000000 #######
#     4.  "SmallDependenceLowGrayLevelEmphasis" 26.000000 ###
#     5.  "LargeDependenceLowGrayLevelEmphasis" 13.000000 #
#     6. "SmallDependenceHighGrayLevelEmphasis" 12.000000 #
#     7.                   "DependenceVariance"  8.000000 #
#     8.              "LargeDependenceEmphasis"  2.000000
#     9.              "SmallDependenceEmphasis"  1.000000
#
# Variable Importance: NUM_NODES:
#     1.                "HighGrayLevelEmphasis" 1728.000000 ################
#     2. "LargeDependenceHighGrayLevelEmphasis" 1568.000000 #############
#     3.                    "DependenceEntropy" 1359.000000 #########
#     4.                 "LowGrayLevelEmphasis" 1255.000000 #######
#     5.  "SmallDependenceLowGrayLevelEmphasis" 1141.000000 #####
#     6.                    "GrayLevelVariance" 1051.000000 ####
#     7.               "GrayLevelNonUniformity" 1045.000000 ####
#     8. "SmallDependenceHighGrayLevelEmphasis" 1040.000000 ####
#     9.  "LargeDependenceLowGrayLevelEmphasis" 963.000000 ##
#    10.              "SmallDependenceEmphasis" 958.000000 ##
#    11.                   "DependenceVariance" 929.000000 ##
#    12.              "LargeDependenceEmphasis" 841.000000
#    13.    "DependenceNonUniformityNormalized" 814.000000
#    14.              "DependenceNonUniformity" 791.000000
#
# Variable Importance: SUM_SCORE:
#     1.                "HighGrayLevelEmphasis" 186265.951748 ################
#     2.                 "LowGrayLevelEmphasis" 131372.135193 ###########
#     3. "LargeDependenceHighGrayLevelEmphasis" 72440.469990 #####
#     4.  "SmallDependenceLowGrayLevelEmphasis" 38224.083531 ##
#     5.                    "DependenceEntropy" 21311.000176 #
#     6. "SmallDependenceHighGrayLevelEmphasis" 20301.993538 #
#     7.  "LargeDependenceLowGrayLevelEmphasis" 19198.163743
#     8.               "GrayLevelNonUniformity" 12931.775286
#     9.                    "GrayLevelVariance" 12784.568796
#    10.              "SmallDependenceEmphasis" 10772.325678
#    11.              "LargeDependenceEmphasis" 9957.519716
#    12.                   "DependenceVariance" 9741.192718
#    13.    "DependenceNonUniformityNormalized" 8779.244264
#    14.              "DependenceNonUniformity" 8662.888675
#
#
#
# Winner takes all: true
# Out-of-bag evaluation: accuracy:0.918999 logloss:0.241859
# Number of trees: 300
# Total number of nodes: 31266
#
# Number of nodes by tree:
# Count: 300 Average: 104.22 StdDev: 9.22704
# Min: 81 Max: 131 Ignored: 0
# ----------------------------------------------
# [  81,  83)  1   0.33%   0.33%
# [  83,  86)  4   1.33%   1.67% #
# [  86,  88)  4   1.33%   3.00% #
# [  88,  91)  8   2.67%   5.67% #
# [  91,  93) 14   4.67%  10.33% ###
# [  93,  96) 21   7.00%  17.33% ####
# [  96,  98) 25   8.33%  25.67% #####
# [  98, 101) 21   7.00%  32.67% ####
# [ 101, 103) 27   9.00%  41.67% #####
# [ 103, 106) 55  18.33%  60.00% ##########
# [ 106, 109) 20   6.67%  66.67% ####
# [ 109, 111) 24   8.00%  74.67% ####
# [ 111, 114) 33  11.00%  85.67% ######
# [ 114, 116) 10   3.33%  89.00% ##
# [ 116, 119) 12   4.00%  93.00% ##
# [ 119, 121)  6   2.00%  95.00% #
# [ 121, 124)  7   2.33%  97.33% #
# [ 124, 126)  3   1.00%  98.33% #
# [ 126, 129)  1   0.33%  98.67%
# [ 129, 131]  4   1.33% 100.00% #
#
# Depth by leafs:
# Count: 15783 Average: 6.92429 StdDev: 2.01516
# Min: 1 Max: 14 Ignored: 0
# ----------------------------------------------
# [  1,  2)    2   0.01%   0.01%
# [  2,  3)   50   0.32%   0.33%
# [  3,  4)  420   2.66%   2.99% #
# [  4,  5) 1295   8.21%  11.20% ####
# [  5,  6) 2249  14.25%  25.45% ########
# [  6,  7) 2920  18.50%  43.95% ##########
# [  7,  8) 2878  18.23%  62.18% ##########
# [  8,  9) 2589  16.40%  78.58% #########
# [  9, 10) 1704  10.80%  89.38% ######
# [ 10, 11)  981   6.22%  95.60% ###
# [ 11, 12)  466   2.95%  98.55% ##
# [ 12, 13)  150   0.95%  99.50% #
# [ 13, 14)   57   0.36%  99.86%
# [ 14, 14]   22   0.14% 100.00%
#
# Number of training obs by leaf:
# Count: 15783 Average: 53.8871 StdDev: 163.696
# Min: 5 Max: 1675 Ignored: 0
# ----------------------------------------------
# [    5,   88) 13984  88.60%  88.60% ##########
# [   88,  172)   764   4.84%  93.44% #
# [  172,  255)   305   1.93%  95.37%
# [  255,  339)   156   0.99%  96.36%
# [  339,  422)    96   0.61%  96.97%
# [  422,  506)    61   0.39%  97.36%
# [  506,  589)    56   0.35%  97.71%
# [  589,  673)    55   0.35%  98.06%
# [  673,  756)    35   0.22%  98.28%
# [  756,  840)    34   0.22%  98.50%
# [  840,  924)    44   0.28%  98.78%
# [  924, 1007)    38   0.24%  99.02%
# [ 1007, 1091)    30   0.19%  99.21%
# [ 1091, 1174)    32   0.20%  99.41%
# [ 1174, 1258)    29   0.18%  99.59%
# [ 1258, 1341)    18   0.11%  99.71%
# [ 1341, 1425)    18   0.11%  99.82%
# [ 1425, 1508)    12   0.08%  99.90%
# [ 1508, 1592)     7   0.04%  99.94%
# [ 1592, 1675]     9   0.06% 100.00%
#
# Attribute in nodes:
# 	1728 : HighGrayLevelEmphasis [NUMERICAL]
# 	1568 : LargeDependenceHighGrayLevelEmphasis [NUMERICAL]
# 	1359 : DependenceEntropy [NUMERICAL]
# 	1255 : LowGrayLevelEmphasis [NUMERICAL]
# 	1141 : SmallDependenceLowGrayLevelEmphasis [NUMERICAL]
# 	1051 : GrayLevelVariance [NUMERICAL]
# 	1045 : GrayLevelNonUniformity [NUMERICAL]
# 	1040 : SmallDependenceHighGrayLevelEmphasis [NUMERICAL]
# 	963 : LargeDependenceLowGrayLevelEmphasis [NUMERICAL]
# 	958 : SmallDependenceEmphasis [NUMERICAL]
# 	929 : DependenceVariance [NUMERICAL]
# 	841 : LargeDependenceEmphasis [NUMERICAL]
# 	814 : DependenceNonUniformityNormalized [NUMERICAL]
# 	791 : DependenceNonUniformity [NUMERICAL]
#
# Attribute in nodes with depth <= 0:
# 	105 : HighGrayLevelEmphasis [NUMERICAL]
# 	85 : LowGrayLevelEmphasis [NUMERICAL]
# 	48 : LargeDependenceHighGrayLevelEmphasis [NUMERICAL]
# 	26 : SmallDependenceLowGrayLevelEmphasis [NUMERICAL]
# 	13 : LargeDependenceLowGrayLevelEmphasis [NUMERICAL]
# 	12 : SmallDependenceHighGrayLevelEmphasis [NUMERICAL]
# 	8 : DependenceVariance [NUMERICAL]
# 	2 : LargeDependenceEmphasis [NUMERICAL]
# 	1 : SmallDependenceEmphasis [NUMERICAL]
#
# Attribute in nodes with depth <= 1:
# 	287 : HighGrayLevelEmphasis [NUMERICAL]
# 	205 : LowGrayLevelEmphasis [NUMERICAL]
# 	149 : LargeDependenceHighGrayLevelEmphasis [NUMERICAL]
# 	87 : SmallDependenceLowGrayLevelEmphasis [NUMERICAL]
# 	45 : SmallDependenceHighGrayLevelEmphasis [NUMERICAL]
# 	40 : LargeDependenceLowGrayLevelEmphasis [NUMERICAL]
# 	14 : GrayLevelNonUniformity [NUMERICAL]
# 	13 : DependenceEntropy [NUMERICAL]
# 	12 : DependenceVariance [NUMERICAL]
# 	11 : SmallDependenceEmphasis [NUMERICAL]
# 	11 : LargeDependenceEmphasis [NUMERICAL]
# 	11 : GrayLevelVariance [NUMERICAL]
# 	7 : DependenceNonUniformity [NUMERICAL]
# 	6 : DependenceNonUniformityNormalized [NUMERICAL]
#
# Attribute in nodes with depth <= 2:
# 	519 : HighGrayLevelEmphasis [NUMERICAL]
# 	326 : LargeDependenceHighGrayLevelEmphasis [NUMERICAL]
# 	317 : LowGrayLevelEmphasis [NUMERICAL]
# 	166 : SmallDependenceLowGrayLevelEmphasis [NUMERICAL]
# 	111 : DependenceEntropy [NUMERICAL]
# 	108 : LargeDependenceLowGrayLevelEmphasis [NUMERICAL]
# 	104 : SmallDependenceHighGrayLevelEmphasis [NUMERICAL]
# 	79 : GrayLevelNonUniformity [NUMERICAL]
# 	64 : GrayLevelVariance [NUMERICAL]
# 	59 : LargeDependenceEmphasis [NUMERICAL]
# 	52 : DependenceNonUniformity [NUMERICAL]
# 	51 : DependenceVariance [NUMERICAL]
# 	44 : SmallDependenceEmphasis [NUMERICAL]
# 	44 : DependenceNonUniformityNormalized [NUMERICAL]
#
# Attribute in nodes with depth <= 3:
# 	755 : HighGrayLevelEmphasis [NUMERICAL]
# 	575 : LargeDependenceHighGrayLevelEmphasis [NUMERICAL]
# 	471 : LowGrayLevelEmphasis [NUMERICAL]
# 	280 : SmallDependenceLowGrayLevelEmphasis [NUMERICAL]
# 	277 : DependenceEntropy [NUMERICAL]
# 	217 : LargeDependenceLowGrayLevelEmphasis [NUMERICAL]
# 	208 : SmallDependenceHighGrayLevelEmphasis [NUMERICAL]
# 	204 : GrayLevelNonUniformity [NUMERICAL]
# 	191 : GrayLevelVariance [NUMERICAL]
# 	162 : LargeDependenceEmphasis [NUMERICAL]
# 	152 : SmallDependenceEmphasis [NUMERICAL]
# 	146 : DependenceVariance [NUMERICAL]
# 	145 : DependenceNonUniformity [NUMERICAL]
# 	133 : DependenceNonUniformityNormalized [NUMERICAL]
#
# Attribute in nodes with depth <= 5:
# 	1224 : HighGrayLevelEmphasis [NUMERICAL]
# 	1049 : LargeDependenceHighGrayLevelEmphasis [NUMERICAL]
# 	810 : LowGrayLevelEmphasis [NUMERICAL]
# 	786 : DependenceEntropy [NUMERICAL]
# 	631 : SmallDependenceLowGrayLevelEmphasis [NUMERICAL]
# 	586 : GrayLevelVariance [NUMERICAL]
# 	580 : GrayLevelNonUniformity [NUMERICAL]
# 	565 : SmallDependenceHighGrayLevelEmphasis [NUMERICAL]
# 	516 : SmallDependenceEmphasis [NUMERICAL]
# 	509 : LargeDependenceLowGrayLevelEmphasis [NUMERICAL]
# 	468 : DependenceVariance [NUMERICAL]
# 	447 : LargeDependenceEmphasis [NUMERICAL]
# 	426 : DependenceNonUniformity [NUMERICAL]
# 	417 : DependenceNonUniformityNormalized [NUMERICAL]
#
# Condition type in nodes:
# 	15483 : HigherCondition
# Condition type in nodes with depth <= 0:
# 	300 : HigherCondition
# Condition type in nodes with depth <= 1:
# 	898 : HigherCondition
# Condition type in nodes with depth <= 2:
# 	2044 : HigherCondition
# Condition type in nodes with depth <= 3:
# 	3916 : HigherCondition
# Condition type in nodes with depth <= 5:
# 	9014 : HigherCondition
# Node format: NOT_SET
#
# Training OOB:
# 	trees: 1, Out-of-bag evaluation: accuracy:0.870002 logloss:4.68559
# 	trees: 12, Out-of-bag evaluation: accuracy:0.902254 logloss:2.28219
# 	trees: 22, Out-of-bag evaluation: accuracy:0.914444 logloss:0.868986
# 	trees: 32, Out-of-bag evaluation: accuracy:0.915123 logloss:0.740354
# 	trees: 42, Out-of-bag evaluation: accuracy:0.918115 logloss:0.730739
# 	trees: 52, Out-of-bag evaluation: accuracy:0.916144 logloss:0.63668
# 	trees: 62, Out-of-bag evaluation: accuracy:0.916823 logloss:0.509578
# 	trees: 72, Out-of-bag evaluation: accuracy:0.918999 logloss:0.420457
# 	trees: 82, Out-of-bag evaluation: accuracy:0.920699 logloss:0.380521
# 	trees: 92, Out-of-bag evaluation: accuracy:0.918115 logloss:0.373836
# 	trees: 102, Out-of-bag evaluation: accuracy:0.918795 logloss:0.332194
# 	trees: 112, Out-of-bag evaluation: accuracy:0.920291 logloss:0.332084
# 	trees: 122, Out-of-bag evaluation: accuracy:0.919203 logloss:0.28919
# 	trees: 132, Out-of-bag evaluation: accuracy:0.920699 logloss:0.289838
# 	trees: 142, Out-of-bag evaluation: accuracy:0.919407 logloss:0.289473
# 	trees: 152, Out-of-bag evaluation: accuracy:0.918999 logloss:0.283097
# 	trees: 162, Out-of-bag evaluation: accuracy:0.919203 logloss:0.283245
# 	trees: 172, Out-of-bag evaluation: accuracy:0.920495 logloss:0.283324
# 	trees: 182, Out-of-bag evaluation: accuracy:0.920495 logloss:0.282451
# 	trees: 192, Out-of-bag evaluation: accuracy:0.919203 logloss:0.282776
# 	trees: 202, Out-of-bag evaluation: accuracy:0.920291 logloss:0.28415
# 	trees: 212, Out-of-bag evaluation: accuracy:0.918115 logloss:0.28408
# 	trees: 222, Out-of-bag evaluation: accuracy:0.916823 logloss:0.284988
# 	trees: 232, Out-of-bag evaluation: accuracy:0.916619 logloss:0.28535
# 	trees: 242, Out-of-bag evaluation: accuracy:0.916619 logloss:0.284896
# 	trees: 252, Out-of-bag evaluation: accuracy:0.917707 logloss:0.242833
# 	trees: 262, Out-of-bag evaluation: accuracy:0.917911 logloss:0.241808
# 	trees: 272, Out-of-bag evaluation: accuracy:0.916823 logloss:0.242223
# 	trees: 282, Out-of-bag evaluation: accuracy:0.91832 logloss:0.242287
# 	trees: 292, Out-of-bag evaluation: accuracy:0.919203 logloss:0.241648
# 	trees: 300, Out-of-bag evaluation: accuracy:0.918999 logloss:0.241859

# %%
# Model features
model.make_inspector().features()
# Out:
# ["DependenceEntropy" (1; #0),
#  "DependenceNonUniformity" (1; #1),
#  "DependenceNonUniformityNormalized" (1; #2),
#  "DependenceVariance" (1; #3),
#  "GrayLevelNonUniformity" (1; #4),
#  "GrayLevelVariance" (1; #5),
#  "HighGrayLevelEmphasis" (1; #6),
#  "LargeDependenceEmphasis" (1; #7),
#  "LargeDependenceHighGrayLevelEmphasis" (1; #8),
#  "LargeDependenceLowGrayLevelEmphasis" (1; #9),
#  "LowGrayLevelEmphasis" (1; #10),
#  "SmallDependenceEmphasis" (1; #11),
#  "SmallDependenceHighGrayLevelEmphasis" (1; #12),
#  "SmallDependenceLowGrayLevelEmphasis" (1; #13)]

# %%
# Feature importance
model.make_inspector().variable_importances()
# Out:
# {'INV_MEAN_MIN_DEPTH': [("HighGrayLevelEmphasis" (1; #6), 0.3174501995171891),
#   ("LowGrayLevelEmphasis" (1; #10), 0.2340022597892797),
#   ("LargeDependenceHighGrayLevelEmphasis" (1; #8), 0.23094112855544255),
#   ("SmallDependenceLowGrayLevelEmphasis" (1; #13), 0.1713616385454668),
#   ("DependenceEntropy" (1; #0), 0.1561783481854716),
#   ("SmallDependenceHighGrayLevelEmphasis" (1; #12), 0.1536215132117769),
#   ("LargeDependenceLowGrayLevelEmphasis" (1; #9), 0.14970941001467813),
#   ("GrayLevelVariance" (1; #5), 0.14534671801077434),
#   ("GrayLevelNonUniformity" (1; #4), 0.14475608926910868),
#   ("LargeDependenceEmphasis" (1; #7), 0.14432176342027492),
#   ("DependenceVariance" (1; #3), 0.1439595873895766),
#   ("SmallDependenceEmphasis" (1; #11), 0.14247383491234913),
#   ("DependenceNonUniformity" (1; #1), 0.1400589002580591),
#   ("DependenceNonUniformityNormalized" (1; #2), 0.13983523374366863)],
#  'SUM_SCORE': [("HighGrayLevelEmphasis" (1; #6), 186265.9517478323),
#   ("LowGrayLevelEmphasis" (1; #10), 131372.13519295),
#   ("LargeDependenceHighGrayLevelEmphasis" (1; #8), 72440.46998998093),
#   ("SmallDependenceLowGrayLevelEmphasis" (1; #13), 38224.083530700416),
#   ("DependenceEntropy" (1; #0), 21311.000175973502),
#   ("SmallDependenceHighGrayLevelEmphasis" (1; #12), 20301.993538279625),
#   ("LargeDependenceLowGrayLevelEmphasis" (1; #9), 19198.16374271748),
#   ("GrayLevelNonUniformity" (1; #4), 12931.775286284887),
#   ("GrayLevelVariance" (1; #5), 12784.568795594221),
#   ("SmallDependenceEmphasis" (1; #11), 10772.325678262265),
#   ("LargeDependenceEmphasis" (1; #7), 9957.519715847331),
#   ("DependenceVariance" (1; #3), 9741.192717752756),
#   ("DependenceNonUniformityNormalized" (1; #2), 8779.244263765957),
#   ("DependenceNonUniformity" (1; #1), 8662.88867504877)],
#  'NUM_AS_ROOT': [("HighGrayLevelEmphasis" (1; #6), 105.0),
#   ("LowGrayLevelEmphasis" (1; #10), 85.0),
#   ("LargeDependenceHighGrayLevelEmphasis" (1; #8), 48.0),
#   ("SmallDependenceLowGrayLevelEmphasis" (1; #13), 26.0),
#   ("LargeDependenceLowGrayLevelEmphasis" (1; #9), 13.0),
#   ("SmallDependenceHighGrayLevelEmphasis" (1; #12), 12.0),
#   ("DependenceVariance" (1; #3), 8.0),
#   ("LargeDependenceEmphasis" (1; #7), 2.0),
#   ("SmallDependenceEmphasis" (1; #11), 1.0)],
#  'NUM_NODES': [("HighGrayLevelEmphasis" (1; #6), 1728.0),
#   ("LargeDependenceHighGrayLevelEmphasis" (1; #8), 1568.0),
#   ("DependenceEntropy" (1; #0), 1359.0),
#   ("LowGrayLevelEmphasis" (1; #10), 1255.0),
#   ("SmallDependenceLowGrayLevelEmphasis" (1; #13), 1141.0),
#   ("GrayLevelVariance" (1; #5), 1051.0),
#   ("GrayLevelNonUniformity" (1; #4), 1045.0),
#   ("SmallDependenceHighGrayLevelEmphasis" (1; #12), 1040.0),
#   ("LargeDependenceLowGrayLevelEmphasis" (1; #9), 963.0),
#   ("SmallDependenceEmphasis" (1; #11), 958.0),
#   ("DependenceVariance" (1; #3), 929.0),
#   ("LargeDependenceEmphasis" (1; #7), 841.0),
#   ("DependenceNonUniformityNormalized" (1; #2), 814.0),
#   ("DependenceNonUniformity" (1; #1), 791.0)]}

# %%
# Model self evaluation
model.make_inspector().evaluation()
# Out:
# Evaluation(num_examples=2835, accuracy=0.9189988966797168, loss=0.24185870554164968, rmse=None, ndcg=None, aucs=None, auuc=None, qini=None)

# %%
logs = model.make_inspector().training_logs()

plt.figure(figsize=(12, 4))
plt.subplot(1, 2, 1)
plt.plot([log.num_trees for log in logs], [log.evaluation.accuracy for log in logs])
plt.xlabel("Number of trees")
plt.ylabel("Accuracy (out-of-bag)")
plt.subplot(1, 2, 2)
plt.plot([log.num_trees for log in logs], [log.evaluation.loss for log in logs])
plt.xlabel("Number of trees")
plt.ylabel("Logloss (out-of-bag)")
plt.show()

# %% [markdown]
# Calculate the score of our hold-out validation dataset

# %%
predictions = model.predict(val_ds)
y_true      = validation_data["label"]

from sklearn.metrics import roc_auc_score
ROC_AUC = roc_auc_score(y_true, predictions)
print("The ROC AUC score is %.5f" % ROC_AUC )
# Out:
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 67ms/step
# The ROC AUC score is 0.99489

# %%
# Compute binary classification metrics with sklearn
import numpy as np
from sklearn.metrics import (
    accuracy_score,
    precision_score,
    recall_score,
    f1_score,
    roc_auc_score,
    average_precision_score,
    confusion_matrix,
    classification_report,
    matthews_corrcoef,
    log_loss,
    brier_score_loss,
)

# Get predictions (probabilities or class labels)
preds = model.predict(test_ds)
# If model outputs probabilities, convert to labels by threshold 0.5
if preds.ndim == 2:
    # For TFDF classification, preds may be class probabilities with shape (N, 2)
    if preds.shape[1] == 2:
        pos_probs = preds[:, 1]
    else:
        # If single-probability column (positive class)
        pos_probs = preds[:, -1]
    y_pred = (pos_probs >= 0.5).astype(int)
else:
    # Already class labels
    y_pred = preds.astype(int)
    pos_probs = None

# Ground truth labels (must be 0/1 integers)
y_true = test_data["label"].astype(int).to_numpy()

# Core metrics
metrics = {}
metrics["accuracy"] = accuracy_score(y_true, y_pred)
metrics["precision"] = precision_score(y_true, y_pred, zero_division=0)
metrics["recall"] = recall_score(y_true, y_pred, zero_division=0)
metrics["f1"] = f1_score(y_true, y_pred, zero_division=0)
metrics["mcc"] = matthews_corrcoef(y_true, y_pred)

# Probabilistic metrics (only if we have probabilities)
if pos_probs is not None:
    metrics["roc_auc"] = roc_auc_score(y_true, pos_probs)
    metrics["pr_auc"] = average_precision_score(y_true, pos_probs)
    metrics["log_loss"] = log_loss(y_true, pos_probs, labels=[0,1])
    metrics["brier_score"] = brier_score_loss(y_true, pos_probs)

# Confusion matrix and detailed report
cm = confusion_matrix(y_true, y_pred, labels=[0,1])
report = classification_report(y_true, y_pred, digits=4)

print("Sklearn binary metrics:")
for k, v in metrics.items():
    print(f"{k}: {v:.4f}")
print("\nConfusion matrix:\n", cm)
print("\nClassification report:\n", report)
# Out:
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 78ms/step
# Sklearn binary metrics:
# accuracy: 0.9581
# precision: 0.8462
# recall: 0.8302
# f1: 0.8381
# mcc: 0.8141
# roc_auc: 0.9819
# pr_auc: 0.9108
# log_loss: 0.1213
# brier_score: 0.0314
#
# Confusion matrix:
#  [[689  16]
#  [ 18  88]]
#
# Classification report:
#                precision    recall  f1-score   support
#
#            0     0.9745    0.9773    0.9759       705
#            1     0.8462    0.8302    0.8381       106
#
#     accuracy                         0.9581       811
#    macro avg     0.9103    0.9037    0.9070       811
# weighted avg     0.9578    0.9581    0.9579       811
