# %%
# Import packages and modules
import numpy  as np
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow_decision_forests as tfdf

from sklearn.model_selection import train_test_split
# Out:
# 2026-08-13 04:20:07.683210: I tensorflow/core/util/port.cc:113] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2026-08-13 04:20:08.078309: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2026-08-13 04:20:12.940500: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
# Check the version of TensorFlow Decision Forests
print("Found TensorFlow Decision Forests v" + tfdf.__version__)
# Out:
# Found TensorFlow Decision Forests v1.9.1

# %%
datasetPath = 'dataset/firstorder/kernel5/dataset.csv'

# %%
# Parameters
datasetPath = "dataset/glrlm/kernel3/1.dataset.csv"

# %%
# train/validation/test = 70/10/20
dataset = pd.read_csv(datasetPath)

train_data, temp_data = train_test_split(dataset, test_size=0.3, random_state=42)
validation_data, test_data = train_test_split(temp_data, test_size=2/3, random_state=42)

# %%
from sklearn.utils.class_weight import compute_class_weight

# tinh class weight tren tap train
classes = np.array([0, 1])
weights = compute_class_weight(class_weight="balanced", classes=classes, y=train_data["label"])
class_weight = {0: weights[0], 1: weights[1]}

# gan sample_weight cho tung dong
train_data["sample_weight"] = train_data["label"].map(class_weight)
validation_data["sample_weight"] = validation_data["label"].map(class_weight)
test_data["sample_weight"] = test_data["label"].map(class_weight)

# Convert the dataset into a TensorFlow dataset.
train_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    train_data, label="label", weight="sample_weight"
)         
val_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    validation_data, label="label", weight="sample_weight"
)
test_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    test_data, label="label", weight="sample_weight"
)
# Out:
# 2026-08-13 04:20:26.660817: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:984] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2026-08-13 04:20:26.662153: W tensorflow/core/common_runtime/gpu/gpu_device.cc:2251] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...

# %%
import keras

# %%
# %%time

# Train a Gradient Boosted Trees model.
model = tfdf.keras.GradientBoostedTreesModel()

# Add evaluation metrics
model.compile(
    metrics=["accuracy"]
)
model.fit(x=train_ds)

# # Train a Gradient Boosted Trees model.
# model = tfdf.keras.GradientBoostedTreesModel(num_trees=1500)
# model.fit(train_ds)
# Out:
# Use /tmp/tmpuj3l2icp as temporary training directory
# Reading training dataset...
# [WARNING 26-08-13 04:20:27.3727 UTC gradient_boosted_trees.cc:1840] "goss_alpha" set but "sampling_method" not equal to "GOSS".
# [WARNING 26-08-13 04:20:27.3731 UTC gradient_boosted_trees.cc:1851] "goss_beta" set but "sampling_method" not equal to "GOSS".
# [WARNING 26-08-13 04:20:27.3731 UTC gradient_boosted_trees.cc:1865] "selective_gradient_boosting_ratio" set but "sampling_method" not equal to "SELGB".
# Training dataset read in 0:00:02.648574. Found 2835 examples.
# Training model...
# Model trained in 0:00:00.407504
# Compiling model...
# [INFO 26-08-13 04:20:30.4601 UTC kernel.cc:1233] Loading model from path /tmp/tmpuj3l2icp/model/ with prefix 332416590a554a78
# [INFO 26-08-13 04:20:30.4630 UTC quick_scorer_extended.cc:911] The binary was compiled without AVX2 support, but your CPU supports it. Enable it for faster model inference.
# [INFO 26-08-13 04:20:30.4631 UTC abstract_model.cc:1362] Engine "GradientBoostedTreesQuickScorerExtended" built
# [INFO 26-08-13 04:20:30.4631 UTC kernel.cc:1061] Use fast generic engine
# Model compiled.
# CPU times: user 6.47 s, sys: 379 ms, total: 6.85 s
# Wall time: 6.92 s

# %%
# Evaluate the model
evaluate = model.evaluate(val_ds, return_dict=True)
print()

for name, value in evaluate.items():
    print(f"{name}: {value:.4f}")
# Out:
# WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 1/1 [==============================] - ETA: 0s - loss: 0.0000e+00 - accuracy: 0.9531
# 1/1 [==============================] - 3s 3s/step - loss: 0.0000e+00 - accuracy: 0.9531
# loss: 0.0000
# accuracy: 0.9531

# %%
# Model Summary
model.summary()
# Out:
# Model: "gradient_boosted_trees_model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
# =================================================================
# Total params: 1 (1.00 Byte)
# Trainable params: 0 (0.00 Byte)
# Non-trainable params: 1 (1.00 Byte)
# _________________________________________________________________
# Type: "GRADIENT_BOOSTED_TREES"
# Task: CLASSIFICATION
# Label: "__LABEL"
#
# Input Features (16):
# 	GrayLevelNonUniformity
# 	GrayLevelNonUniformityNormalized
# 	GrayLevelVariance
# 	HighGrayLevelRunEmphasis
# 	LongRunEmphasis
# 	LongRunHighGrayLevelEmphasis
# 	LongRunLowGrayLevelEmphasis
# 	LowGrayLevelRunEmphasis
# 	RunEntropy
# 	RunLengthNonUniformity
# 	RunLengthNonUniformityNormalized
# 	RunPercentage
# 	RunVariance
# 	ShortRunEmphasis
# 	ShortRunHighGrayLevelEmphasis
# 	ShortRunLowGrayLevelEmphasis
#
# Trained with weights
#
# Variable Importance: INV_MEAN_MIN_DEPTH:
#     1.     "LongRunHighGrayLevelEmphasis"  1.000000 ################
#     2.    "ShortRunHighGrayLevelEmphasis"  0.243890 #
#     3.         "HighGrayLevelRunEmphasis"  0.203088
#     4.                       "RunEntropy"  0.196311
#     5. "GrayLevelNonUniformityNormalized"  0.194879
#     6.     "ShortRunLowGrayLevelEmphasis"  0.191683
#     7.           "GrayLevelNonUniformity"  0.188555
#     8.      "LongRunLowGrayLevelEmphasis"  0.187819
#     9.          "LowGrayLevelRunEmphasis"  0.187725
#    10.                "GrayLevelVariance"  0.185149
#    11.                      "RunVariance"  0.183768
#    12.                  "LongRunEmphasis"  0.181490
#    13.                 "ShortRunEmphasis"  0.180742
#    14. "RunLengthNonUniformityNormalized"  0.179630
#    15.           "RunLengthNonUniformity"  0.179501
#    16.                    "RunPercentage"  0.179055
#
# Variable Importance: NUM_AS_ROOT:
#     1. "LongRunHighGrayLevelEmphasis" 40.000000
#
# Variable Importance: NUM_NODES:
#     1.     "LongRunHighGrayLevelEmphasis" 267.000000 ################
#     2.    "ShortRunHighGrayLevelEmphasis" 93.000000 #####
#     3.                       "RunEntropy" 69.000000 ###
#     4.         "HighGrayLevelRunEmphasis" 49.000000 ##
#     5.     "ShortRunLowGrayLevelEmphasis" 49.000000 ##
#     6. "GrayLevelNonUniformityNormalized" 43.000000 ##
#     7.                "GrayLevelVariance" 38.000000 #
#     8.          "LowGrayLevelRunEmphasis" 38.000000 #
#     9.           "GrayLevelNonUniformity" 34.000000 #
#    10.      "LongRunLowGrayLevelEmphasis" 32.000000 #
#    11.                      "RunVariance" 31.000000 #
#    12.                  "LongRunEmphasis" 21.000000
#    13.                 "ShortRunEmphasis" 14.000000
#    14. "RunLengthNonUniformityNormalized" 11.000000
#    15.           "RunLengthNonUniformity"  9.000000
#    16.                    "RunPercentage"  8.000000
#
# Variable Importance: SUM_SCORE:
#     1.     "LongRunHighGrayLevelEmphasis" 2716.865378 ################
#     2.    "ShortRunHighGrayLevelEmphasis" 146.394062
#     3.                       "RunEntropy" 59.285790
#     4. "GrayLevelNonUniformityNormalized" 58.686631
#     5.           "GrayLevelNonUniformity" 48.510466
#     6.     "ShortRunLowGrayLevelEmphasis" 43.595843
#     7.         "HighGrayLevelRunEmphasis" 37.646428
#     8.                      "RunVariance" 36.552747
#     9.                  "LongRunEmphasis" 32.472763
#    10.                "GrayLevelVariance" 25.812794
#    11.          "LowGrayLevelRunEmphasis" 17.364784
#    12.      "LongRunLowGrayLevelEmphasis" 16.151979
#    13. "RunLengthNonUniformityNormalized" 10.251669
#    14.                 "ShortRunEmphasis"  7.749893
#    15.                    "RunPercentage"  1.625665
#    16.           "RunLengthNonUniformity"  0.394037
#
#
#
# Loss: BINOMIAL_LOG_LIKELIHOOD
# Validation loss value: 0.497588
# Number of trees per iteration: 1
# Node format: NOT_SET
# Number of trees: 40
# Total number of nodes: 1652
#
# Number of nodes by tree:
# Count: 40 Average: 41.3 StdDev: 6.83447
# Min: 21 Max: 57 Ignored: 0
# ----------------------------------------------
# [ 21, 22) 1   2.50%   2.50% #
# [ 22, 24) 0   0.00%   2.50%
# [ 24, 26) 0   0.00%   2.50%
# [ 26, 28) 1   2.50%   5.00% #
# [ 28, 30) 1   2.50%   7.50% #
# [ 30, 32) 0   0.00%   7.50%
# [ 32, 33) 0   0.00%   7.50%
# [ 33, 35) 2   5.00%  12.50% ###
# [ 35, 37) 5  12.50%  25.00% #######
# [ 37, 39) 1   2.50%  27.50% #
# [ 39, 41) 3   7.50%  35.00% ####
# [ 41, 43) 3   7.50%  42.50% ####
# [ 43, 45) 7  17.50%  60.00% ##########
# [ 45, 46) 7  17.50%  77.50% ##########
# [ 46, 48) 4  10.00%  87.50% ######
# [ 48, 50) 4  10.00%  97.50% ######
# [ 50, 52) 0   0.00%  97.50%
# [ 52, 54) 0   0.00%  97.50%
# [ 54, 56) 0   0.00%  97.50%
# [ 56, 57] 1   2.50% 100.00% #
#
# Depth by leafs:
# Count: 846 Average: 4.63121 StdDev: 0.70202
# Min: 2 Max: 5 Ignored: 0
# ----------------------------------------------
# [ 2, 3)  12   1.42%   1.42%
# [ 3, 4)  74   8.75%  10.17% #
# [ 4, 5) 128  15.13%  25.30% ##
# [ 5, 5] 632  74.70% 100.00% ##########
#
# Number of training obs by leaf:
# Count: 846 Average: 121.466 StdDev: 297.981
# Min: 5 Max: 2263 Ignored: 0
# ----------------------------------------------
# [    5,  117) 689  81.44%  81.44% ##########
# [  117,  230)  60   7.09%  88.53% #
# [  230,  343)  23   2.72%  91.25%
# [  343,  456)   6   0.71%  91.96%
# [  456,  569)  23   2.72%  94.68%
# [  569,  682)   3   0.35%  95.04%
# [  682,  795)   1   0.12%  95.15%
# [  795,  908)   1   0.12%  95.27%
# [  908, 1021)  12   1.42%  96.69%
# [ 1021, 1134)   3   0.35%  97.04%
# [ 1134, 1247)   3   0.35%  97.40%
# [ 1247, 1360)   2   0.24%  97.64%
# [ 1360, 1473)   8   0.95%  98.58%
# [ 1473, 1586)   5   0.59%  99.17%
# [ 1586, 1699)   3   0.35%  99.53%
# [ 1699, 1812)   1   0.12%  99.65%
# [ 1812, 1925)   0   0.00%  99.65%
# [ 1925, 2038)   1   0.12%  99.76%
# [ 2038, 2151)   1   0.12%  99.88%
# [ 2151, 2263]   1   0.12% 100.00%
#
# Attribute in nodes:
# 	267 : LongRunHighGrayLevelEmphasis [NUMERICAL]
# 	93 : ShortRunHighGrayLevelEmphasis [NUMERICAL]
# 	69 : RunEntropy [NUMERICAL]
# 	49 : ShortRunLowGrayLevelEmphasis [NUMERICAL]
# 	49 : HighGrayLevelRunEmphasis [NUMERICAL]
# 	43 : GrayLevelNonUniformityNormalized [NUMERICAL]
# 	38 : LowGrayLevelRunEmphasis [NUMERICAL]
# 	38 : GrayLevelVariance [NUMERICAL]
# 	34 : GrayLevelNonUniformity [NUMERICAL]
# 	32 : LongRunLowGrayLevelEmphasis [NUMERICAL]
# 	31 : RunVariance [NUMERICAL]
# 	21 : LongRunEmphasis [NUMERICAL]
# 	14 : ShortRunEmphasis [NUMERICAL]
# 	11 : RunLengthNonUniformityNormalized [NUMERICAL]
# 	9 : RunLengthNonUniformity [NUMERICAL]
# 	8 : RunPercentage [NUMERICAL]
#
# Attribute in nodes with depth <= 0:
# 	40 : LongRunHighGrayLevelEmphasis [NUMERICAL]
#
# Attribute in nodes with depth <= 1:
# 	74 : LongRunHighGrayLevelEmphasis [NUMERICAL]
# 	27 : ShortRunHighGrayLevelEmphasis [NUMERICAL]
# 	9 : HighGrayLevelRunEmphasis [NUMERICAL]
# 	3 : RunEntropy [NUMERICAL]
# 	2 : ShortRunLowGrayLevelEmphasis [NUMERICAL]
# 	2 : LowGrayLevelRunEmphasis [NUMERICAL]
# 	2 : LongRunLowGrayLevelEmphasis [NUMERICAL]
# 	1 : GrayLevelNonUniformityNormalized [NUMERICAL]
#
# Attribute in nodes with depth <= 2:
# 	130 : LongRunHighGrayLevelEmphasis [NUMERICAL]
# 	38 : ShortRunHighGrayLevelEmphasis [NUMERICAL]
# 	20 : GrayLevelNonUniformityNormalized [NUMERICAL]
# 	17 : HighGrayLevelRunEmphasis [NUMERICAL]
# 	16 : ShortRunLowGrayLevelEmphasis [NUMERICAL]
# 	13 : GrayLevelNonUniformity [NUMERICAL]
# 	12 : RunEntropy [NUMERICAL]
# 	8 : GrayLevelVariance [NUMERICAL]
# 	7 : LowGrayLevelRunEmphasis [NUMERICAL]
# 	3 : LongRunLowGrayLevelEmphasis [NUMERICAL]
# 	2 : RunVariance [NUMERICAL]
# 	1 : ShortRunEmphasis [NUMERICAL]
# 	1 : LongRunEmphasis [NUMERICAL]
#
# Attribute in nodes with depth <= 3:
# 	192 : LongRunHighGrayLevelEmphasis [NUMERICAL]
# 	58 : ShortRunHighGrayLevelEmphasis [NUMERICAL]
# 	33 : HighGrayLevelRunEmphasis [NUMERICAL]
# 	32 : GrayLevelNonUniformityNormalized [NUMERICAL]
# 	31 : RunEntropy [NUMERICAL]
# 	27 : ShortRunLowGrayLevelEmphasis [NUMERICAL]
# 	21 : LowGrayLevelRunEmphasis [NUMERICAL]
# 	21 : GrayLevelNonUniformity [NUMERICAL]
# 	20 : LongRunLowGrayLevelEmphasis [NUMERICAL]
# 	19 : GrayLevelVariance [NUMERICAL]
# 	13 : RunVariance [NUMERICAL]
# 	8 : LongRunEmphasis [NUMERICAL]
# 	6 : ShortRunEmphasis [NUMERICAL]
# 	5 : RunLengthNonUniformityNormalized [NUMERICAL]
# 	2 : RunPercentage [NUMERICAL]
# 	2 : RunLengthNonUniformity [NUMERICAL]
#
# Attribute in nodes with depth <= 5:
# 	267 : LongRunHighGrayLevelEmphasis [NUMERICAL]
# 	93 : ShortRunHighGrayLevelEmphasis [NUMERICAL]
# 	69 : RunEntropy [NUMERICAL]
# 	49 : ShortRunLowGrayLevelEmphasis [NUMERICAL]
# 	49 : HighGrayLevelRunEmphasis [NUMERICAL]
# 	43 : GrayLevelNonUniformityNormalized [NUMERICAL]
# 	38 : LowGrayLevelRunEmphasis [NUMERICAL]
# 	38 : GrayLevelVariance [NUMERICAL]
# 	34 : GrayLevelNonUniformity [NUMERICAL]
# 	32 : LongRunLowGrayLevelEmphasis [NUMERICAL]
# 	31 : RunVariance [NUMERICAL]
# 	21 : LongRunEmphasis [NUMERICAL]
# 	14 : ShortRunEmphasis [NUMERICAL]
# 	11 : RunLengthNonUniformityNormalized [NUMERICAL]
# 	9 : RunLengthNonUniformity [NUMERICAL]
# 	8 : RunPercentage [NUMERICAL]
#
# Condition type in nodes:
# 	806 : HigherCondition
# Condition type in nodes with depth <= 0:
# 	40 : HigherCondition
# Condition type in nodes with depth <= 1:
# 	120 : HigherCondition
# Condition type in nodes with depth <= 2:
# 	268 : HigherCondition
# Condition type in nodes with depth <= 3:
# 	490 : HigherCondition
# Condition type in nodes with depth <= 5:
# 	806 : HigherCondition
#
# Training logs:
# Number of iteration to final model: 40
# 	Iter:1 train-loss:1.223525 valid-loss:1.243316  train-accuracy:0.949197 valid-accuracy:0.879330
# 	Iter:2 train-loss:1.090354 valid-loss:1.126901  train-accuracy:0.959849 valid-accuracy:0.908423
# 	Iter:3 train-loss:0.978391 valid-loss:1.032166  train-accuracy:0.958505 valid-accuracy:0.903947
# 	Iter:4 train-loss:0.884280 valid-loss:0.953012  train-accuracy:0.958953 valid-accuracy:0.906185
# 	Iter:5 train-loss:0.799674 valid-loss:0.886652  train-accuracy:0.961524 valid-accuracy:0.908423
# 	Iter:6 train-loss:0.729244 valid-loss:0.831217  train-accuracy:0.965555 valid-accuracy:0.889445
# 	Iter:16 train-loss:0.350198 valid-loss:0.570467  train-accuracy:0.970258 valid-accuracy:0.898397
# 	Iter:26 train-loss:0.220317 valid-loss:0.499695  train-accuracy:0.974845 valid-accuracy:0.917375
# 	Iter:36 train-loss:0.161567 valid-loss:0.509795  train-accuracy:0.981994 valid-accuracy:0.921851
# 	Iter:46 train-loss:0.126624 valid-loss:0.514495  train-accuracy:0.989814 valid-accuracy:0.926326
# 	Iter:56 train-loss:0.104101 valid-loss:0.528724  train-accuracy:0.992833 valid-accuracy:0.926326
# 	Iter:66 train-loss:0.086483 valid-loss:0.552750  train-accuracy:0.994849 valid-accuracy:0.926326

# %%
# Model features
model.make_inspector().features()
# Out:
# ["GrayLevelNonUniformity" (1; #0),
#  "GrayLevelNonUniformityNormalized" (1; #1),
#  "GrayLevelVariance" (1; #2),
#  "HighGrayLevelRunEmphasis" (1; #3),
#  "LongRunEmphasis" (1; #4),
#  "LongRunHighGrayLevelEmphasis" (1; #5),
#  "LongRunLowGrayLevelEmphasis" (1; #6),
#  "LowGrayLevelRunEmphasis" (1; #7),
#  "RunEntropy" (1; #8),
#  "RunLengthNonUniformity" (1; #9),
#  "RunLengthNonUniformityNormalized" (1; #10),
#  "RunPercentage" (1; #11),
#  "RunVariance" (1; #12),
#  "ShortRunEmphasis" (1; #13),
#  "ShortRunHighGrayLevelEmphasis" (1; #14),
#  "ShortRunLowGrayLevelEmphasis" (1; #15)]

# %%
# Feature importance
model.make_inspector().variable_importances()
# Out:
# {'INV_MEAN_MIN_DEPTH': [("LongRunHighGrayLevelEmphasis" (1; #5), 1.0),
#   ("ShortRunHighGrayLevelEmphasis" (1; #14), 0.24388953867138116),
#   ("HighGrayLevelRunEmphasis" (1; #3), 0.2030879454345064),
#   ("RunEntropy" (1; #8), 0.19631082222173943),
#   ("GrayLevelNonUniformityNormalized" (1; #1), 0.19487893754560018),
#   ("ShortRunLowGrayLevelEmphasis" (1; #15), 0.19168277003157377),
#   ("GrayLevelNonUniformity" (1; #0), 0.18855527197924224),
#   ("LongRunLowGrayLevelEmphasis" (1; #6), 0.1878185250105209),
#   ("LowGrayLevelRunEmphasis" (1; #7), 0.18772513489649506),
#   ("GrayLevelVariance" (1; #2), 0.18514943701908493),
#   ("RunVariance" (1; #12), 0.18376822979344148),
#   ("LongRunEmphasis" (1; #4), 0.18148998164126154),
#   ("ShortRunEmphasis" (1; #13), 0.18074155932394798),
#   ("RunLengthNonUniformityNormalized" (1; #10), 0.17962978537914548),
#   ("RunLengthNonUniformity" (1; #9), 0.17950094402929231),
#   ("RunPercentage" (1; #11), 0.17905484191371204)],
#  'SUM_SCORE': [("LongRunHighGrayLevelEmphasis" (1; #5), 2716.865378118733),
#   ("ShortRunHighGrayLevelEmphasis" (1; #14), 146.3940618600913),
#   ("RunEntropy" (1; #8), 59.28578982051195),
#   ("GrayLevelNonUniformityNormalized" (1; #1), 58.68663132641552),
#   ("GrayLevelNonUniformity" (1; #0), 48.510466072103384),
#   ("ShortRunLowGrayLevelEmphasis" (1; #15), 43.595843147900986),
#   ("HighGrayLevelRunEmphasis" (1; #3), 37.646427642773084),
#   ("RunVariance" (1; #12), 36.552747010755084),
#   ("LongRunEmphasis" (1; #4), 32.47276288460006),
#   ("GrayLevelVariance" (1; #2), 25.81279415838914),
#   ("LowGrayLevelRunEmphasis" (1; #7), 17.364784219973345),
#   ("LongRunLowGrayLevelEmphasis" (1; #6), 16.151979471099768),
#   ("RunLengthNonUniformityNormalized" (1; #10), 10.25166937441252),
#   ("ShortRunEmphasis" (1; #13), 7.7498928943238905),
#   ("RunPercentage" (1; #11), 1.6256654896221976),
#   ("RunLengthNonUniformity" (1; #9), 0.3940372686597558)],
#  'NUM_AS_ROOT': [("LongRunHighGrayLevelEmphasis" (1; #5), 40.0)],
#  'NUM_NODES': [("LongRunHighGrayLevelEmphasis" (1; #5), 267.0),
#   ("ShortRunHighGrayLevelEmphasis" (1; #14), 93.0),
#   ("RunEntropy" (1; #8), 69.0),
#   ("HighGrayLevelRunEmphasis" (1; #3), 49.0),
#   ("ShortRunLowGrayLevelEmphasis" (1; #15), 49.0),
#   ("GrayLevelNonUniformityNormalized" (1; #1), 43.0),
#   ("GrayLevelVariance" (1; #2), 38.0),
#   ("LowGrayLevelRunEmphasis" (1; #7), 38.0),
#   ("GrayLevelNonUniformity" (1; #0), 34.0),
#   ("LongRunLowGrayLevelEmphasis" (1; #6), 32.0),
#   ("RunVariance" (1; #12), 31.0),
#   ("LongRunEmphasis" (1; #4), 21.0),
#   ("ShortRunEmphasis" (1; #13), 14.0),
#   ("RunLengthNonUniformityNormalized" (1; #10), 11.0),
#   ("RunLengthNonUniformity" (1; #9), 9.0),
#   ("RunPercentage" (1; #11), 8.0)]}

# %%
# Model self evaluation
model.make_inspector().evaluation()
# Out:
# Evaluation(num_examples=None, accuracy=0.926326334476471, loss=0.49758830666542053, rmse=None, ndcg=None, aucs=None, auuc=None, qini=None)

# %%
logs = model.make_inspector().training_logs()

plt.figure(figsize=(12, 4))
plt.subplot(1, 2, 1)
plt.plot([log.num_trees for log in logs], [log.evaluation.accuracy for log in logs])
plt.xlabel("Number of trees")
plt.ylabel("Accuracy (out-of-bag)")
plt.subplot(1, 2, 2)
plt.plot([log.num_trees for log in logs], [log.evaluation.loss for log in logs])
plt.xlabel("Number of trees")
plt.ylabel("Logloss (out-of-bag)")
plt.show()

# %% [markdown]
# Calculate the score of our hold-out validation dataset

# %%
predictions = model.predict(val_ds)
y_true      = validation_data["label"]

from sklearn.metrics import roc_auc_score
ROC_AUC = roc_auc_score(y_true, predictions)
print("The ROC AUC score is %.5f" % ROC_AUC )
# Out:
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 60ms/step
# The ROC AUC score is 0.98011

# %%
# Compute binary classification metrics with sklearn
import numpy as np
from sklearn.metrics import (
    accuracy_score,
    precision_score,
    recall_score,
    f1_score,
    roc_auc_score,
    average_precision_score,
    confusion_matrix,
    classification_report,
    matthews_corrcoef,
    log_loss,
    brier_score_loss,
)

# Get predictions (probabilities or class labels)
preds = model.predict(test_ds)
# If model outputs probabilities, convert to labels by threshold 0.5
if preds.ndim == 2:
    # For TFDF classification, preds may be class probabilities with shape (N, 2)
    if preds.shape[1] == 2:
        pos_probs = preds[:, 1]
    else:
        # If single-probability column (positive class)
        pos_probs = preds[:, -1]
    y_pred = (pos_probs >= 0.5).astype(int)
else:
    # Already class labels
    y_pred = preds.astype(int)
    pos_probs = None

# Ground truth labels (must be 0/1 integers)
y_true = test_data["label"].astype(int).to_numpy()

# Core metrics
metrics = {}
metrics["accuracy"] = accuracy_score(y_true, y_pred)
metrics["precision"] = precision_score(y_true, y_pred, zero_division=0)
metrics["recall"] = recall_score(y_true, y_pred, zero_division=0)
metrics["f1"] = f1_score(y_true, y_pred, zero_division=0)
metrics["mcc"] = matthews_corrcoef(y_true, y_pred)

# Probabilistic metrics (only if we have probabilities)
if pos_probs is not None:
    metrics["roc_auc"] = roc_auc_score(y_true, pos_probs)
    metrics["pr_auc"] = average_precision_score(y_true, pos_probs)
    metrics["log_loss"] = log_loss(y_true, pos_probs, labels=[0,1])
    metrics["brier_score"] = brier_score_loss(y_true, pos_probs)

# Confusion matrix and detailed report
cm = confusion_matrix(y_true, y_pred, labels=[0,1])
report = classification_report(y_true, y_pred, digits=4)

print("Sklearn binary metrics:")
for k, v in metrics.items():
    print(f"{k}: {v:.4f}")
print("\nConfusion matrix:\n", cm)
print("\nClassification report:\n", report)
# Out:
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 71ms/step
# Sklearn binary metrics:
# accuracy: 0.9519
# precision: 0.7891
# recall: 0.8938
# f1: 0.8382
# mcc: 0.8122
# roc_auc: 0.9811
# pr_auc: 0.9325
# log_loss: 0.1346
# brier_score: 0.0368
#
# Confusion matrix:
#  [[671  27]
#  [ 12 101]]
#
# Classification report:
#                precision    recall  f1-score   support
#
#            0     0.9824    0.9613    0.9718       698
#            1     0.7891    0.8938    0.8382       113
#
#     accuracy                         0.9519       811
#    macro avg     0.8857    0.9276    0.9050       811
# weighted avg     0.9555    0.9519    0.9531       811
