# %%
# Import packages and modules
import numpy  as np
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow_decision_forests as tfdf

from sklearn.model_selection import train_test_split
# Out:
# 2026-08-13 04:25:11.344090: I tensorflow/core/util/port.cc:113] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2026-08-13 04:25:11.713244: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2026-08-13 04:25:16.727892: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
# Check the version of TensorFlow Decision Forests
print("Found TensorFlow Decision Forests v" + tfdf.__version__)
# Out:
# Found TensorFlow Decision Forests v1.9.1

# %%
datasetPath = 'dataset/firstorder/kernel5/dataset.csv'

# %%
# Parameters
datasetPath = "dataset/ngtdm/kernel3/1.dataset.csv"

# %%
# train/validation/test = 70/10/20
dataset = pd.read_csv(datasetPath)

train_data, temp_data = train_test_split(dataset, test_size=0.3, random_state=42)
validation_data, test_data = train_test_split(temp_data, test_size=2/3, random_state=42)

# %%
from sklearn.utils.class_weight import compute_class_weight

# tinh class weight tren tap train
classes = np.array([0, 1])
weights = compute_class_weight(class_weight="balanced", classes=classes, y=train_data["label"])
class_weight = {0: weights[0], 1: weights[1]}

# gan sample_weight cho tung dong
train_data["sample_weight"] = train_data["label"].map(class_weight)
validation_data["sample_weight"] = validation_data["label"].map(class_weight)
test_data["sample_weight"] = test_data["label"].map(class_weight)

# Convert the dataset into a TensorFlow dataset.
train_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    train_data, label="label", weight="sample_weight"
)         
val_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    validation_data, label="label", weight="sample_weight"
)
test_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    test_data, label="label", weight="sample_weight"
)
# Out:
# 2026-08-13 04:25:30.429776: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:984] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2026-08-13 04:25:30.432169: W tensorflow/core/common_runtime/gpu/gpu_device.cc:2251] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...

# %%
import keras

# %%
# %%time

# Train a Random Forest model.
model = tfdf.keras.RandomForestModel()

# Add evaluation metrics
model.compile(
    metrics=["accuracy"]
)
model.fit(x=train_ds)

# # Train a Gradient Boosted Trees model.
# model = tfdf.keras.GradientBoostedTreesModel(num_trees=1500)
# model.fit(train_ds)
# Out:
# Use /tmp/tmpnu7h77nf as temporary training directory
# Reading training dataset...
# Training dataset read in 0:00:02.614043. Found 2835 examples.
# Training model...
# Model trained in 0:00:00.245496
# Compiling model...
# [INFO 26-08-13 04:25:33.3659 UTC kernel.cc:1233] Loading model from path /tmp/tmpnu7h77nf/model/ with prefix b9d7c59bc6284677
# [INFO 26-08-13 04:25:33.4419 UTC decision_forest.cc:734] Model loaded with 300 root(s), 55088 node(s), and 5 input feature(s).
# [INFO 26-08-13 04:25:33.4420 UTC abstract_model.cc:1362] Engine "RandomForestOptPred" built
# [INFO 26-08-13 04:25:33.4420 UTC kernel.cc:1061] Use fast generic engine
# Model compiled.
# CPU times: user 6.55 s, sys: 125 ms, total: 6.68 s
# Wall time: 6.21 s

# %%
# Evaluate the model
evaluate = model.evaluate(val_ds, return_dict=True)
print()

for name, value in evaluate.items():
    print(f"{name}: {value:.4f}")
# Out:
# WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 1/1 [==============================] - ETA: 0s - loss: 0.0000e+00 - accuracy: 0.9333
# 1/1 [==============================] - 3s 3s/step - loss: 0.0000e+00 - accuracy: 0.9333
# loss: 0.0000
# accuracy: 0.9333

# %%
# Model Summary
model.summary()
# Out:
# Model: "random_forest_model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
# =================================================================
# Total params: 1 (1.00 Byte)
# Trainable params: 0 (0.00 Byte)
# Non-trainable params: 1 (1.00 Byte)
# _________________________________________________________________
# Type: "RANDOM_FOREST"
# Task: CLASSIFICATION
# Label: "__LABEL"
#
# Input Features (5):
# 	Busyness
# 	Coarseness
# 	Complexity
# 	Contrast
# 	Strength
#
# Trained with weights
#
# Variable Importance: INV_MEAN_MIN_DEPTH:
#     1.   "Busyness"  0.730541 ################
#     2. "Complexity"  0.228194 #
#     3. "Coarseness"  0.215915 #
#     4.   "Contrast"  0.180854
#     5.   "Strength"  0.176689
#
# Variable Importance: NUM_AS_ROOT:
#     1.   "Busyness" 220.000000 ################
#     2. "Coarseness" 80.000000
#
# Variable Importance: NUM_NODES:
#     1.   "Busyness" 7488.000000 ################
#     2.   "Strength" 5308.000000 ###
#     3. "Complexity" 5102.000000 ##
#     4.   "Contrast" 4801.000000
#     5. "Coarseness" 4695.000000
#
# Variable Importance: SUM_SCORE:
#     1.   "Busyness" 236043.786691 ################
#     2. "Complexity" 100542.127826 ###
#     3. "Coarseness" 74630.959906 #
#     4.   "Contrast" 65773.734831
#     5.   "Strength" 62301.037390
#
#
#
# Winner takes all: true
# Out-of-bag evaluation: accuracy:0.876457 logloss:0.426132
# Number of trees: 300
# Total number of nodes: 55088
#
# Number of nodes by tree:
# Count: 300 Average: 183.627 StdDev: 11.9992
# Min: 149 Max: 217 Ignored: 0
# ----------------------------------------------
# [ 149, 152)  2   0.67%   0.67% #
# [ 152, 155)  0   0.00%   0.67%
# [ 155, 159)  3   1.00%   1.67% #
# [ 159, 162)  6   2.00%   3.67% ##
# [ 162, 166)  7   2.33%   6.00% ##
# [ 166, 169)  9   3.00%   9.00% ##
# [ 169, 173) 24   8.00%  17.00% ######
# [ 173, 176) 29   9.67%  26.67% #######
# [ 176, 180) 40  13.33%  40.00% ##########
# [ 180, 183) 14   4.67%  44.67% ####
# [ 183, 186) 37  12.33%  57.00% #########
# [ 186, 190) 33  11.00%  68.00% ########
# [ 190, 193) 12   4.00%  72.00% ###
# [ 193, 197) 38  12.67%  84.67% ##########
# [ 197, 200) 22   7.33%  92.00% ######
# [ 200, 204) 10   3.33%  95.33% ###
# [ 204, 207)  4   1.33%  96.67% #
# [ 207, 211)  7   2.33%  99.00% ##
# [ 211, 214)  1   0.33%  99.33%
# [ 214, 217]  2   0.67% 100.00% #
#
# Depth by leafs:
# Count: 27694 Average: 7.742 StdDev: 1.99419
# Min: 2 Max: 15 Ignored: 0
# ----------------------------------------------
# [  2,  3)    4   0.01%   0.01%
# [  3,  4)  253   0.91%   0.93%
# [  4,  5)  872   3.15%   4.08% ##
# [  5,  6) 2338   8.44%  12.52% ####
# [  6,  7) 4125  14.89%  27.41% #######
# [  7,  8) 5532  19.98%  47.39% ##########
# [  8,  9) 5246  18.94%  66.33% #########
# [  9, 10) 4148  14.98%  81.31% #######
# [ 10, 11) 2685   9.70%  91.01% #####
# [ 11, 12) 1481   5.35%  96.35% ###
# [ 12, 13)  688   2.48%  98.84% #
# [ 13, 14)  243   0.88%  99.71%
# [ 14, 15)   53   0.19%  99.91%
# [ 15, 15]   26   0.09% 100.00%
#
# Number of training obs by leaf:
# Count: 27694 Average: 30.7106 StdDev: 93.2376
# Min: 5 Max: 1211 Ignored: 0
# ----------------------------------------------
# [    5,   65) 25373  91.62%  91.62% ##########
# [   65,  125)  1103   3.98%  95.60%
# [  125,  186)   403   1.46%  97.06%
# [  186,  246)   210   0.76%  97.82%
# [  246,  306)   154   0.56%  98.37%
# [  306,  367)    86   0.31%  98.68%
# [  367,  427)    46   0.17%  98.85%
# [  427,  487)    16   0.06%  98.91%
# [  487,  548)    13   0.05%  98.95%
# [  548,  608)    25   0.09%  99.04%
# [  608,  668)    30   0.11%  99.15%
# [  668,  729)    39   0.14%  99.29%
# [  729,  789)    30   0.11%  99.40%
# [  789,  849)    48   0.17%  99.57%
# [  849,  910)    43   0.16%  99.73%
# [  910,  970)    30   0.11%  99.84%
# [  970, 1030)    22   0.08%  99.92%
# [ 1030, 1091)    18   0.06%  99.98%
# [ 1091, 1151)     2   0.01%  99.99%
# [ 1151, 1211]     3   0.01% 100.00%
#
# Attribute in nodes:
# 	7488 : Busyness [NUMERICAL]
# 	5308 : Strength [NUMERICAL]
# 	5102 : Complexity [NUMERICAL]
# 	4801 : Contrast [NUMERICAL]
# 	4695 : Coarseness [NUMERICAL]
#
# Attribute in nodes with depth <= 0:
# 	220 : Busyness [NUMERICAL]
# 	80 : Coarseness [NUMERICAL]
#
# Attribute in nodes with depth <= 1:
# 	411 : Busyness [NUMERICAL]
# 	225 : Coarseness [NUMERICAL]
# 	158 : Complexity [NUMERICAL]
# 	97 : Contrast [NUMERICAL]
# 	9 : Strength [NUMERICAL]
#
# Attribute in nodes with depth <= 2:
# 	1024 : Busyness [NUMERICAL]
# 	339 : Complexity [NUMERICAL]
# 	303 : Coarseness [NUMERICAL]
# 	242 : Contrast [NUMERICAL]
# 	188 : Strength [NUMERICAL]
#
# Attribute in nodes with depth <= 3:
# 	1683 : Busyness [NUMERICAL]
# 	838 : Complexity [NUMERICAL]
# 	720 : Strength [NUMERICAL]
# 	505 : Coarseness [NUMERICAL]
# 	489 : Contrast [NUMERICAL]
#
# Attribute in nodes with depth <= 5:
# 	3874 : Busyness [NUMERICAL]
# 	2352 : Complexity [NUMERICAL]
# 	2326 : Strength [NUMERICAL]
# 	1809 : Coarseness [NUMERICAL]
# 	1754 : Contrast [NUMERICAL]
#
# Condition type in nodes:
# 	27394 : HigherCondition
# Condition type in nodes with depth <= 0:
# 	300 : HigherCondition
# Condition type in nodes with depth <= 1:
# 	900 : HigherCondition
# Condition type in nodes with depth <= 2:
# 	2096 : HigherCondition
# Condition type in nodes with depth <= 3:
# 	4235 : HigherCondition
# Condition type in nodes with depth <= 5:
# 	12115 : HigherCondition
# Node format: NOT_SET
#
# Training OOB:
# 	trees: 1, Out-of-bag evaluation: accuracy:0.814852 logloss:6.6734
# 	trees: 12, Out-of-bag evaluation: accuracy:0.802431 logloss:4.8928
# 	trees: 22, Out-of-bag evaluation: accuracy:0.861123 logloss:1.27636
# 	trees: 32, Out-of-bag evaluation: accuracy:0.866437 logloss:1.08017
# 	trees: 42, Out-of-bag evaluation: accuracy:0.875829 logloss:0.933056
# 	trees: 52, Out-of-bag evaluation: accuracy:0.872966 logloss:0.828667
# 	trees: 62, Out-of-bag evaluation: accuracy:0.877672 logloss:0.752242
# 	trees: 72, Out-of-bag evaluation: accuracy:0.879516 logloss:0.754123
# 	trees: 82, Out-of-bag evaluation: accuracy:0.876848 logloss:0.674772
# 	trees: 92, Out-of-bag evaluation: accuracy:0.877878 logloss:0.6716
# 	trees: 102, Out-of-bag evaluation: accuracy:0.877466 logloss:0.666856
# 	trees: 112, Out-of-bag evaluation: accuracy:0.879516 logloss:0.586216
# 	trees: 123, Out-of-bag evaluation: accuracy:0.877466 logloss:0.587409
# 	trees: 133, Out-of-bag evaluation: accuracy:0.878084 logloss:0.545512
# 	trees: 144, Out-of-bag evaluation: accuracy:0.876859 logloss:0.545294
# 	trees: 154, Out-of-bag evaluation: accuracy:0.878084 logloss:0.546226
# 	trees: 164, Out-of-bag evaluation: accuracy:0.880535 logloss:0.505804
# 	trees: 174, Out-of-bag evaluation: accuracy:0.877878 logloss:0.46769
# 	trees: 184, Out-of-bag evaluation: accuracy:0.874614 logloss:0.467859
# 	trees: 195, Out-of-bag evaluation: accuracy:0.875633 logloss:0.466535
# 	trees: 205, Out-of-bag evaluation: accuracy:0.877477 logloss:0.427584
# 	trees: 215, Out-of-bag evaluation: accuracy:0.874006 logloss:0.429361
# 	trees: 225, Out-of-bag evaluation: accuracy:0.876663 logloss:0.428241
# 	trees: 235, Out-of-bag evaluation: accuracy:0.873594 logloss:0.427703
# 	trees: 245, Out-of-bag evaluation: accuracy:0.876457 logloss:0.426743
# 	trees: 255, Out-of-bag evaluation: accuracy:0.875438 logloss:0.426196
# 	trees: 265, Out-of-bag evaluation: accuracy:0.877683 logloss:0.426707
# 	trees: 275, Out-of-bag evaluation: accuracy:0.875839 logloss:0.426167
# 	trees: 285, Out-of-bag evaluation: accuracy:0.876251 logloss:0.425946
# 	trees: 295, Out-of-bag evaluation: accuracy:0.877683 logloss:0.426108
# 	trees: 300, Out-of-bag evaluation: accuracy:0.876457 logloss:0.426132

# %%
# Model features
model.make_inspector().features()
# Out:
# ["Busyness" (1; #0),
#  "Coarseness" (1; #1),
#  "Complexity" (1; #2),
#  "Contrast" (1; #3),
#  "Strength" (1; #4)]

# %%
# Feature importance
model.make_inspector().variable_importances()
# Out:
# {'INV_MEAN_MIN_DEPTH': [("Busyness" (1; #0), 0.7305408714947195),
#   ("Complexity" (1; #2), 0.22819354365385977),
#   ("Coarseness" (1; #1), 0.21591463997897822),
#   ("Contrast" (1; #3), 0.18085433609219745),
#   ("Strength" (1; #4), 0.1766886614303176)],
#  'SUM_SCORE': [("Busyness" (1; #0), 236043.78669147837),
#   ("Complexity" (1; #2), 100542.12782611664),
#   ("Coarseness" (1; #1), 74630.95990634903),
#   ("Contrast" (1; #3), 65773.73483088051),
#   ("Strength" (1; #4), 62301.037389944846)],
#  'NUM_AS_ROOT': [("Busyness" (1; #0), 220.0), ("Coarseness" (1; #1), 80.0)],
#  'NUM_NODES': [("Busyness" (1; #0), 7488.0),
#   ("Strength" (1; #4), 5308.0),
#   ("Complexity" (1; #2), 5102.0),
#   ("Contrast" (1; #3), 4801.0),
#   ("Coarseness" (1; #1), 4695.0)]}

# %%
# Model self evaluation
model.make_inspector().evaluation()
# Out:
# Evaluation(num_examples=2835, accuracy=0.8764572603811817, loss=0.42613193223259577, rmse=None, ndcg=None, aucs=None, auuc=None, qini=None)

# %%
logs = model.make_inspector().training_logs()

plt.figure(figsize=(12, 4))
plt.subplot(1, 2, 1)
plt.plot([log.num_trees for log in logs], [log.evaluation.accuracy for log in logs])
plt.xlabel("Number of trees")
plt.ylabel("Accuracy (out-of-bag)")
plt.subplot(1, 2, 2)
plt.plot([log.num_trees for log in logs], [log.evaluation.loss for log in logs])
plt.xlabel("Number of trees")
plt.ylabel("Logloss (out-of-bag)")
plt.show()

# %% [markdown]
# Calculate the score of our hold-out validation dataset

# %%
predictions = model.predict(val_ds)
y_true      = validation_data["label"]

from sklearn.metrics import roc_auc_score
ROC_AUC = roc_auc_score(y_true, predictions)
print("The ROC AUC score is %.5f" % ROC_AUC )
# Out:
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 63ms/step
# The ROC AUC score is 0.97403

# %%
# Compute binary classification metrics with sklearn
import numpy as np
from sklearn.metrics import (
    accuracy_score,
    precision_score,
    recall_score,
    f1_score,
    roc_auc_score,
    average_precision_score,
    confusion_matrix,
    classification_report,
    matthews_corrcoef,
    log_loss,
    brier_score_loss,
)

# Get predictions (probabilities or class labels)
preds = model.predict(test_ds)
# If model outputs probabilities, convert to labels by threshold 0.5
if preds.ndim == 2:
    # For TFDF classification, preds may be class probabilities with shape (N, 2)
    if preds.shape[1] == 2:
        pos_probs = preds[:, 1]
    else:
        # If single-probability column (positive class)
        pos_probs = preds[:, -1]
    y_pred = (pos_probs >= 0.5).astype(int)
else:
    # Already class labels
    y_pred = preds.astype(int)
    pos_probs = None

# Ground truth labels (must be 0/1 integers)
y_true = test_data["label"].astype(int).to_numpy()

# Core metrics
metrics = {}
metrics["accuracy"] = accuracy_score(y_true, y_pred)
metrics["precision"] = precision_score(y_true, y_pred, zero_division=0)
metrics["recall"] = recall_score(y_true, y_pred, zero_division=0)
metrics["f1"] = f1_score(y_true, y_pred, zero_division=0)
metrics["mcc"] = matthews_corrcoef(y_true, y_pred)

# Probabilistic metrics (only if we have probabilities)
if pos_probs is not None:
    metrics["roc_auc"] = roc_auc_score(y_true, pos_probs)
    metrics["pr_auc"] = average_precision_score(y_true, pos_probs)
    metrics["log_loss"] = log_loss(y_true, pos_probs, labels=[0,1])
    metrics["brier_score"] = brier_score_loss(y_true, pos_probs)

# Confusion matrix and detailed report
cm = confusion_matrix(y_true, y_pred, labels=[0,1])
report = classification_report(y_true, y_pred, digits=4)

print("Sklearn binary metrics:")
for k, v in metrics.items():
    print(f"{k}: {v:.4f}")
print("\nConfusion matrix:\n", cm)
print("\nClassification report:\n", report)
# Out:
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 73ms/step
# Sklearn binary metrics:
# accuracy: 0.9309
# precision: 0.7018
# recall: 0.7843
# f1: 0.7407
# mcc: 0.7025
# roc_auc: 0.9502
# pr_auc: 0.8249
# log_loss: 0.1804
# brier_score: 0.0520
#
# Confusion matrix:
#  [[675  34]
#  [ 22  80]]
#
# Classification report:
#                precision    recall  f1-score   support
#
#            0     0.9684    0.9520    0.9602       709
#            1     0.7018    0.7843    0.7407       102
#
#     accuracy                         0.9309       811
#    macro avg     0.8351    0.8682    0.8505       811
# weighted avg     0.9349    0.9309    0.9326       811
