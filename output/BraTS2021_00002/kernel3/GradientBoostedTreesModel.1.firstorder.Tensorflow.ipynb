# %%
# Import packages and modules
import numpy  as np
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow_decision_forests as tfdf

from sklearn.model_selection import train_test_split
# Out:
# 2026-08-13 04:18:14.151326: I tensorflow/core/util/port.cc:113] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2026-08-13 04:18:14.533256: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2026-08-13 04:18:19.323614: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
# Check the version of TensorFlow Decision Forests
print("Found TensorFlow Decision Forests v" + tfdf.__version__)
# Out:
# Found TensorFlow Decision Forests v1.9.1

# %%
datasetPath = 'dataset/firstorder/kernel5/dataset.csv'

# %%
# Parameters
datasetPath = "dataset/firstorder/kernel3/1.dataset.csv"

# %%
# train/validation/test = 70/10/20
dataset = pd.read_csv(datasetPath)

train_data, temp_data = train_test_split(dataset, test_size=0.3, random_state=42)
validation_data, test_data = train_test_split(temp_data, test_size=2/3, random_state=42)

# %%
from sklearn.utils.class_weight import compute_class_weight

# tinh class weight tren tap train
classes = np.array([0, 1])
weights = compute_class_weight(class_weight="balanced", classes=classes, y=train_data["label"])
class_weight = {0: weights[0], 1: weights[1]}

# gan sample_weight cho tung dong
train_data["sample_weight"] = train_data["label"].map(class_weight)
validation_data["sample_weight"] = validation_data["label"].map(class_weight)
test_data["sample_weight"] = test_data["label"].map(class_weight)

# Convert the dataset into a TensorFlow dataset.
train_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    train_data, label="label", weight="sample_weight"
)         
val_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    validation_data, label="label", weight="sample_weight"
)
test_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    test_data, label="label", weight="sample_weight"
)
# Out:
# 2026-08-13 04:18:33.788580: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:984] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2026-08-13 04:18:33.789986: W tensorflow/core/common_runtime/gpu/gpu_device.cc:2251] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...

# %%
import keras

# %%
# %%time

# Train a Gradient Boosted Trees model.
model = tfdf.keras.GradientBoostedTreesModel()

# Add evaluation metrics
model.compile(
    metrics=["accuracy"]
)
model.fit(x=train_ds)

# # Train a Gradient Boosted Trees model.
# model = tfdf.keras.GradientBoostedTreesModel(num_trees=1500)
# model.fit(train_ds)
# Out:
# Use /tmp/tmpfdu9_er2 as temporary training directory
# [WARNING 26-08-13 04:18:33.9499 UTC gradient_boosted_trees.cc:1840] "goss_alpha" set but "sampling_method" not equal to "GOSS".
# [WARNING 26-08-13 04:18:33.9503 UTC gradient_boosted_trees.cc:1851] "goss_beta" set but "sampling_method" not equal to "GOSS".
# [WARNING 26-08-13 04:18:33.9503 UTC gradient_boosted_trees.cc:1865] "selective_gradient_boosting_ratio" set but "sampling_method" not equal to "SELGB".
# Reading training dataset...
# Training dataset read in 0:00:02.624340. Found 2835 examples.
# Training model...
# Model trained in 0:00:00.371801
# Compiling model...
# [INFO 26-08-13 04:18:37.6698 UTC kernel.cc:1233] Loading model from path /tmp/tmpfdu9_er2/model/ with prefix 6745bc90c7db4026
# [INFO 26-08-13 04:18:37.6729 UTC quick_scorer_extended.cc:911] The binary was compiled without AVX2 support, but your CPU supports it. Enable it for faster model inference.
# [INFO 26-08-13 04:18:37.6731 UTC abstract_model.cc:1362] Engine "GradientBoostedTreesQuickScorerExtended" built
# [INFO 26-08-13 04:18:37.6731 UTC kernel.cc:1061] Use fast generic engine
# Model compiled.
# CPU times: user 6.34 s, sys: 451 ms, total: 6.79 s
# Wall time: 6.96 s

# %%
# Evaluate the model
evaluate = model.evaluate(val_ds, return_dict=True)
print()

for name, value in evaluate.items():
    print(f"{name}: {value:.4f}")
# Out:
# WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 1/1 [==============================] - ETA: 0s - loss: 0.0000e+00 - accuracy: 0.9506
# 1/1 [==============================] - 3s 3s/step - loss: 0.0000e+00 - accuracy: 0.9506
# loss: 0.0000
# accuracy: 0.9506

# %%
# Model Summary
model.summary()
# Out:
# Model: "gradient_boosted_trees_model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
# =================================================================
# Total params: 1 (1.00 Byte)
# Trainable params: 0 (0.00 Byte)
# Non-trainable params: 1 (1.00 Byte)
# _________________________________________________________________
# Type: "GRADIENT_BOOSTED_TREES"
# Task: CLASSIFICATION
# Label: "__LABEL"
#
# Input Features (18):
# 	10Percentile
# 	90Percentile
# 	Energy
# 	Entropy
# 	InterquartileRange
# 	Kurtosis
# 	Maximum
# 	Mean
# 	MeanAbsoluteDeviation
# 	Median
# 	Minimum
# 	Range
# 	RobustMeanAbsoluteDeviation
# 	RootMeanSquared
# 	Skewness
# 	TotalEnergy
# 	Uniformity
# 	Variance
#
# Trained with weights
#
# Variable Importance: INV_MEAN_MIN_DEPTH:
#     1.                      "Median"  0.385755 ################
#     2.                        "Mean"  0.325895 ###########
#     3.                "10Percentile"  0.218504 ###
#     4.                     "Minimum"  0.203394 ##
#     5.                     "Maximum"  0.195762 #
#     6.                 "TotalEnergy"  0.194689 #
#     7.                "90Percentile"  0.194432 #
#     8.                  "Uniformity"  0.190862 #
#     9.             "RootMeanSquared"  0.188653 #
#    10.                       "Range"  0.184177
#    11.                     "Entropy"  0.182555
#    12.                    "Skewness"  0.181496
#    13.                      "Energy"  0.180979
#    14.          "InterquartileRange"  0.179877
#    15.                    "Kurtosis"  0.177891
#    16. "RobustMeanAbsoluteDeviation"  0.177088
#    17.                    "Variance"  0.176405
#    18.       "MeanAbsoluteDeviation"  0.175447
#
# Variable Importance: NUM_AS_ROOT:
#     1.            "Mean" 14.000000 ################
#     2.          "Median" 11.000000 ############
#     3.     "TotalEnergy"  3.000000 ##
#     4. "RootMeanSquared"  1.000000
#
# Variable Importance: NUM_NODES:
#     1.                      "Median" 92.000000 ################
#     2.                "10Percentile" 68.000000 ###########
#     3.                        "Mean" 61.000000 #########
#     4.                     "Minimum" 57.000000 #########
#     5.                     "Maximum" 54.000000 ########
#     6.                  "Uniformity" 45.000000 ######
#     7.                    "Skewness" 42.000000 ######
#     8.                "90Percentile" 41.000000 ######
#     9.                     "Entropy" 38.000000 #####
#    10.                    "Kurtosis" 35.000000 ####
#    11.                       "Range" 34.000000 ####
#    12.                      "Energy" 18.000000 #
#    13.          "InterquartileRange" 18.000000 #
#    14. "RobustMeanAbsoluteDeviation" 17.000000 #
#    15.             "RootMeanSquared" 16.000000 #
#    16.                    "Variance" 15.000000
#    17.       "MeanAbsoluteDeviation" 14.000000
#    18.                 "TotalEnergy" 10.000000
#
# Variable Importance: SUM_SCORE:
#     1.                        "Mean" 2006.391383 ################
#     2.                      "Median" 419.202153 ###
#     3.                "10Percentile" 148.232962 #
#     4.             "RootMeanSquared" 109.495535
#     5.                  "Uniformity" 81.075016
#     6.                     "Entropy" 56.561145
#     7.                     "Minimum" 54.519125
#     8.                     "Maximum" 52.570886
#     9.                "90Percentile" 50.240604
#    10.                    "Skewness" 42.790431
#    11.          "InterquartileRange" 40.504336
#    12.                 "TotalEnergy" 35.454107
#    13.                    "Kurtosis" 33.227229
#    14.                       "Range" 32.628121
#    15.                    "Variance" 17.711875
#    16. "RobustMeanAbsoluteDeviation" 17.523447
#    17.       "MeanAbsoluteDeviation" 11.975514
#    18.                      "Energy"  5.411906
#
#
#
# Loss: BINOMIAL_LOG_LIKELIHOOD
# Validation loss value: 0.557492
# Number of trees per iteration: 1
# Node format: NOT_SET
# Number of trees: 29
# Total number of nodes: 1379
#
# Number of nodes by tree:
# Count: 29 Average: 47.5517 StdDev: 7.68153
# Min: 33 Max: 59 Ignored: 0
# ----------------------------------------------
# [ 33, 34) 3  10.34%  10.34% ########
# [ 34, 35) 0   0.00%  10.34%
# [ 35, 37) 1   3.45%  13.79% ###
# [ 37, 38) 0   0.00%  13.79%
# [ 38, 39) 0   0.00%  13.79%
# [ 39, 41) 2   6.90%  20.69% #####
# [ 41, 42) 0   0.00%  20.69%
# [ 42, 43) 0   0.00%  20.69%
# [ 43, 45) 2   6.90%  27.59% #####
# [ 45, 46) 4  13.79%  41.38% ##########
# [ 46, 47) 0   0.00%  41.38%
# [ 47, 49) 1   3.45%  44.83% ###
# [ 49, 50) 3  10.34%  55.17% ########
# [ 50, 51) 0   0.00%  55.17%
# [ 51, 53) 3  10.34%  65.52% ########
# [ 53, 54) 3  10.34%  75.86% ########
# [ 54, 55) 0   0.00%  75.86%
# [ 55, 57) 4  13.79%  89.66% ##########
# [ 57, 58) 1   3.45%  93.10% ###
# [ 58, 59] 2   6.90% 100.00% #####
#
# Depth by leafs:
# Count: 704 Average: 4.76562 StdDev: 0.5695
# Min: 2 Max: 5 Ignored: 0
# ----------------------------------------------
# [ 2, 3)   8   1.14%   1.14%
# [ 3, 4)  27   3.84%   4.97%
# [ 4, 5)  87  12.36%  17.33% #
# [ 5, 5] 582  82.67% 100.00% ##########
#
# Number of training obs by leaf:
# Count: 704 Average: 105.825 StdDev: 288.509
# Min: 5 Max: 1957 Ignored: 0
# ----------------------------------------------
# [    5,  102) 579  82.24%  82.24% ##########
# [  102,  200)  52   7.39%  89.63% #
# [  200,  297)  22   3.12%  92.76%
# [  297,  395)  10   1.42%  94.18%
# [  395,  493)   4   0.57%  94.74%
# [  493,  590)   2   0.28%  95.03%
# [  590,  688)   2   0.28%  95.31%
# [  688,  786)   4   0.57%  95.88%
# [  786,  883)   1   0.14%  96.02%
# [  883,  981)   2   0.28%  96.31%
# [  981, 1079)   4   0.57%  96.88%
# [ 1079, 1176)   3   0.43%  97.30%
# [ 1176, 1274)   2   0.28%  97.59%
# [ 1274, 1372)   1   0.14%  97.73%
# [ 1372, 1469)   1   0.14%  97.87%
# [ 1469, 1567)   3   0.43%  98.30%
# [ 1567, 1665)   7   0.99%  99.29%
# [ 1665, 1762)   2   0.28%  99.57%
# [ 1762, 1860)   2   0.28%  99.86%
# [ 1860, 1957]   1   0.14% 100.00%
#
# Attribute in nodes:
# 	92 : Median [NUMERICAL]
# 	68 : 10Percentile [NUMERICAL]
# 	61 : Mean [NUMERICAL]
# 	57 : Minimum [NUMERICAL]
# 	54 : Maximum [NUMERICAL]
# 	45 : Uniformity [NUMERICAL]
# 	42 : Skewness [NUMERICAL]
# 	41 : 90Percentile [NUMERICAL]
# 	38 : Entropy [NUMERICAL]
# 	35 : Kurtosis [NUMERICAL]
# 	34 : Range [NUMERICAL]
# 	18 : InterquartileRange [NUMERICAL]
# 	18 : Energy [NUMERICAL]
# 	17 : RobustMeanAbsoluteDeviation [NUMERICAL]
# 	16 : RootMeanSquared [NUMERICAL]
# 	15 : Variance [NUMERICAL]
# 	14 : MeanAbsoluteDeviation [NUMERICAL]
# 	10 : TotalEnergy [NUMERICAL]
#
# Attribute in nodes with depth <= 0:
# 	14 : Mean [NUMERICAL]
# 	11 : Median [NUMERICAL]
# 	3 : TotalEnergy [NUMERICAL]
# 	1 : RootMeanSquared [NUMERICAL]
#
# Attribute in nodes with depth <= 1:
# 	26 : Median [NUMERICAL]
# 	24 : Mean [NUMERICAL]
# 	13 : 10Percentile [NUMERICAL]
# 	5 : Minimum [NUMERICAL]
# 	5 : Maximum [NUMERICAL]
# 	5 : 90Percentile [NUMERICAL]
# 	4 : TotalEnergy [NUMERICAL]
# 	3 : RootMeanSquared [NUMERICAL]
# 	1 : Uniformity [NUMERICAL]
# 	1 : Energy [NUMERICAL]
#
# Attribute in nodes with depth <= 2:
# 	45 : Median [NUMERICAL]
# 	31 : Mean [NUMERICAL]
# 	24 : 10Percentile [NUMERICAL]
# 	16 : 90Percentile [NUMERICAL]
# 	15 : Uniformity [NUMERICAL]
# 	15 : Minimum [NUMERICAL]
# 	10 : Maximum [NUMERICAL]
# 	8 : RootMeanSquared [NUMERICAL]
# 	8 : Range [NUMERICAL]
# 	8 : Entropy [NUMERICAL]
# 	7 : TotalEnergy [NUMERICAL]
# 	5 : Energy [NUMERICAL]
# 	1 : Skewness [NUMERICAL]
# 	1 : RobustMeanAbsoluteDeviation [NUMERICAL]
# 	1 : InterquartileRange [NUMERICAL]
#
# Attribute in nodes with depth <= 3:
# 	57 : Median [NUMERICAL]
# 	50 : Mean [NUMERICAL]
# 	40 : 10Percentile [NUMERICAL]
# 	33 : Maximum [NUMERICAL]
# 	31 : Minimum [NUMERICAL]
# 	28 : Uniformity [NUMERICAL]
# 	26 : 90Percentile [NUMERICAL]
# 	17 : Skewness [NUMERICAL]
# 	17 : Range [NUMERICAL]
# 	17 : InterquartileRange [NUMERICAL]
# 	17 : Entropy [NUMERICAL]
# 	12 : RootMeanSquared [NUMERICAL]
# 	9 : Energy [NUMERICAL]
# 	8 : TotalEnergy [NUMERICAL]
# 	7 : RobustMeanAbsoluteDeviation [NUMERICAL]
# 	6 : Variance [NUMERICAL]
# 	6 : Kurtosis [NUMERICAL]
# 	3 : MeanAbsoluteDeviation [NUMERICAL]
#
# Attribute in nodes with depth <= 5:
# 	92 : Median [NUMERICAL]
# 	68 : 10Percentile [NUMERICAL]
# 	61 : Mean [NUMERICAL]
# 	57 : Minimum [NUMERICAL]
# 	54 : Maximum [NUMERICAL]
# 	45 : Uniformity [NUMERICAL]
# 	42 : Skewness [NUMERICAL]
# 	41 : 90Percentile [NUMERICAL]
# 	38 : Entropy [NUMERICAL]
# 	35 : Kurtosis [NUMERICAL]
# 	34 : Range [NUMERICAL]
# 	18 : InterquartileRange [NUMERICAL]
# 	18 : Energy [NUMERICAL]
# 	17 : RobustMeanAbsoluteDeviation [NUMERICAL]
# 	16 : RootMeanSquared [NUMERICAL]
# 	15 : Variance [NUMERICAL]
# 	14 : MeanAbsoluteDeviation [NUMERICAL]
# 	10 : TotalEnergy [NUMERICAL]
#
# Condition type in nodes:
# 	675 : HigherCondition
# Condition type in nodes with depth <= 0:
# 	29 : HigherCondition
# Condition type in nodes with depth <= 1:
# 	87 : HigherCondition
# Condition type in nodes with depth <= 2:
# 	195 : HigherCondition
# Condition type in nodes with depth <= 3:
# 	384 : HigherCondition
# Condition type in nodes with depth <= 5:
# 	675 : HigherCondition
#
# Training logs:
# Number of iteration to final model: 29
# 	Iter:1 train-loss:1.225201 valid-loss:1.255413  train-accuracy:0.950238 valid-accuracy:0.874438
# 	Iter:2 train-loss:1.093962 valid-loss:1.152576  train-accuracy:0.953965 valid-accuracy:0.869468
# 	Iter:3 train-loss:0.983874 valid-loss:1.064192  train-accuracy:0.956670 valid-accuracy:0.862272
# 	Iter:4 train-loss:0.886786 valid-loss:0.994223  train-accuracy:0.962635 valid-accuracy:0.860045
# 	Iter:5 train-loss:0.805319 valid-loss:0.936155  train-accuracy:0.966015 valid-accuracy:0.852849
# 	Iter:6 train-loss:0.733236 valid-loss:0.887641  train-accuracy:0.968547 valid-accuracy:0.850622
# 	Iter:16 train-loss:0.350365 valid-loss:0.638639  train-accuracy:0.973835 valid-accuracy:0.857302
# 	Iter:26 train-loss:0.215072 valid-loss:0.574258  train-accuracy:0.982211 valid-accuracy:0.882828
# 	Iter:36 train-loss:0.150933 valid-loss:0.567118  train-accuracy:0.984742 valid-accuracy:0.871178
# 	Iter:46 train-loss:0.112009 valid-loss:0.592281  train-accuracy:0.988852 valid-accuracy:0.868952
# 	Iter:56 train-loss:0.087981 valid-loss:0.605894  train-accuracy:0.993186 valid-accuracy:0.868952

# %%
# Model features
model.make_inspector().features()
# Out:
# ["10Percentile" (1; #0),
#  "90Percentile" (1; #1),
#  "Energy" (1; #2),
#  "Entropy" (1; #3),
#  "InterquartileRange" (1; #4),
#  "Kurtosis" (1; #5),
#  "Maximum" (1; #6),
#  "Mean" (1; #7),
#  "MeanAbsoluteDeviation" (1; #8),
#  "Median" (1; #9),
#  "Minimum" (1; #10),
#  "Range" (1; #11),
#  "RobustMeanAbsoluteDeviation" (1; #12),
#  "RootMeanSquared" (1; #13),
#  "Skewness" (1; #14),
#  "TotalEnergy" (1; #15),
#  "Uniformity" (1; #16),
#  "Variance" (1; #17)]

# %%
# Feature importance
model.make_inspector().variable_importances()
# Out:
# {'INV_MEAN_MIN_DEPTH': [("Median" (1; #9), 0.3857552222537063),
#   ("Mean" (1; #7), 0.325895250425389),
#   ("10Percentile" (1; #0), 0.21850356167849144),
#   ("Minimum" (1; #10), 0.20339430520848106),
#   ("Maximum" (1; #6), 0.19576193617451365),
#   ("TotalEnergy" (1; #15), 0.19468857693248337),
#   ("90Percentile" (1; #1), 0.1944321465417299),
#   ("Uniformity" (1; #16), 0.19086176658853027),
#   ("RootMeanSquared" (1; #13), 0.18865275287608407),
#   ("Range" (1; #11), 0.18417659409864404),
#   ("Entropy" (1; #3), 0.1825551093770392),
#   ("Skewness" (1; #14), 0.18149608382433127),
#   ("Energy" (1; #2), 0.18097901717103254),
#   ("InterquartileRange" (1; #4), 0.17987744941931375),
#   ("Kurtosis" (1; #5), 0.17789119997978842),
#   ("RobustMeanAbsoluteDeviation" (1; #12), 0.17708836600633848),
#   ("Variance" (1; #17), 0.17640488995361314),
#   ("MeanAbsoluteDeviation" (1; #8), 0.17544741312336423)],
#  'SUM_SCORE': [("Mean" (1; #7), 2006.3913826022704),
#   ("Median" (1; #9), 419.2021533895276),
#   ("10Percentile" (1; #0), 148.2329618295361),
#   ("RootMeanSquared" (1; #13), 109.49553530514109),
#   ("Uniformity" (1; #16), 81.0750159861081),
#   ("Entropy" (1; #3), 56.561145341278475),
#   ("Minimum" (1; #10), 54.519125081163864),
#   ("Maximum" (1; #6), 52.57088628351924),
#   ("90Percentile" (1; #1), 50.24060372912231),
#   ("Skewness" (1; #14), 42.79043091389586),
#   ("InterquartileRange" (1; #4), 40.50433550175165),
#   ("TotalEnergy" (1; #15), 35.45410728221913),
#   ("Kurtosis" (1; #5), 33.2272294117395),
#   ("Range" (1; #11), 32.628120519058314),
#   ("Variance" (1; #17), 17.711874814075742),
#   ("RobustMeanAbsoluteDeviation" (1; #12), 17.523447460436415),
#   ("MeanAbsoluteDeviation" (1; #8), 11.975513520517577),
#   ("Energy" (1; #2), 5.411906052457622)],
#  'NUM_AS_ROOT': [("Mean" (1; #7), 14.0),
#   ("Median" (1; #9), 11.0),
#   ("TotalEnergy" (1; #15), 3.0),
#   ("RootMeanSquared" (1; #13), 1.0)],
#  'NUM_NODES': [("Median" (1; #9), 92.0),
#   ("10Percentile" (1; #0), 68.0),
#   ("Mean" (1; #7), 61.0),
#   ("Minimum" (1; #10), 57.0),
#   ("Maximum" (1; #6), 54.0),
#   ("Uniformity" (1; #16), 45.0),
#   ("Skewness" (1; #14), 42.0),
#   ("90Percentile" (1; #1), 41.0),
#   ("Entropy" (1; #3), 38.0),
#   ("Kurtosis" (1; #5), 35.0),
#   ("Range" (1; #11), 34.0),
#   ("Energy" (1; #2), 18.0),
#   ("InterquartileRange" (1; #4), 18.0),
#   ("RobustMeanAbsoluteDeviation" (1; #12), 17.0),
#   ("RootMeanSquared" (1; #13), 16.0),
#   ("Variance" (1; #17), 15.0),
#   ("MeanAbsoluteDeviation" (1; #8), 14.0),
#   ("TotalEnergy" (1; #15), 10.0)]}

# %%
# Model self evaluation
model.make_inspector().evaluation()
# Out:
# Evaluation(num_examples=None, accuracy=0.8689515590667725, loss=0.5574923157691956, rmse=None, ndcg=None, aucs=None, auuc=None, qini=None)

# %%
logs = model.make_inspector().training_logs()

plt.figure(figsize=(12, 4))
plt.subplot(1, 2, 1)
plt.plot([log.num_trees for log in logs], [log.evaluation.accuracy for log in logs])
plt.xlabel("Number of trees")
plt.ylabel("Accuracy (out-of-bag)")
plt.subplot(1, 2, 2)
plt.plot([log.num_trees for log in logs], [log.evaluation.loss for log in logs])
plt.xlabel("Number of trees")
plt.ylabel("Logloss (out-of-bag)")
plt.show()

# %% [markdown]
# Calculate the score of our hold-out validation dataset

# %%
predictions = model.predict(val_ds)
y_true      = validation_data["label"]

from sklearn.metrics import roc_auc_score
ROC_AUC = roc_auc_score(y_true, predictions)
print("The ROC AUC score is %.5f" % ROC_AUC )
# Out:
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 62ms/step
# The ROC AUC score is 0.97549

# %%
# Compute binary classification metrics with sklearn
import numpy as np
from sklearn.metrics import (
    accuracy_score,
    precision_score,
    recall_score,
    f1_score,
    roc_auc_score,
    average_precision_score,
    confusion_matrix,
    classification_report,
    matthews_corrcoef,
    log_loss,
    brier_score_loss,
)

# Get predictions (probabilities or class labels)
preds = model.predict(test_ds)
# If model outputs probabilities, convert to labels by threshold 0.5
if preds.ndim == 2:
    # For TFDF classification, preds may be class probabilities with shape (N, 2)
    if preds.shape[1] == 2:
        pos_probs = preds[:, 1]
    else:
        # If single-probability column (positive class)
        pos_probs = preds[:, -1]
    y_pred = (pos_probs >= 0.5).astype(int)
else:
    # Already class labels
    y_pred = preds.astype(int)
    pos_probs = None

# Ground truth labels (must be 0/1 integers)
y_true = test_data["label"].astype(int).to_numpy()

# Core metrics
metrics = {}
metrics["accuracy"] = accuracy_score(y_true, y_pred)
metrics["precision"] = precision_score(y_true, y_pred, zero_division=0)
metrics["recall"] = recall_score(y_true, y_pred, zero_division=0)
metrics["f1"] = f1_score(y_true, y_pred, zero_division=0)
metrics["mcc"] = matthews_corrcoef(y_true, y_pred)

# Probabilistic metrics (only if we have probabilities)
if pos_probs is not None:
    metrics["roc_auc"] = roc_auc_score(y_true, pos_probs)
    metrics["pr_auc"] = average_precision_score(y_true, pos_probs)
    metrics["log_loss"] = log_loss(y_true, pos_probs, labels=[0,1])
    metrics["brier_score"] = brier_score_loss(y_true, pos_probs)

# Confusion matrix and detailed report
cm = confusion_matrix(y_true, y_pred, labels=[0,1])
report = classification_report(y_true, y_pred, digits=4)

print("Sklearn binary metrics:")
for k, v in metrics.items():
    print(f"{k}: {v:.4f}")
print("\nConfusion matrix:\n", cm)
print("\nClassification report:\n", report)
# Out:
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 72ms/step
# Sklearn binary metrics:
# accuracy: 0.9383
# precision: 0.7642
# recall: 0.8174
# f1: 0.7899
# mcc: 0.7544
# roc_auc: 0.9670
# pr_auc: 0.8772
# log_loss: 0.1780
# brier_score: 0.0482
#
# Confusion matrix:
#  [[667  29]
#  [ 21  94]]
#
# Classification report:
#                precision    recall  f1-score   support
#
#            0     0.9695    0.9583    0.9639       696
#            1     0.7642    0.8174    0.7899       115
#
#     accuracy                         0.9383       811
#    macro avg     0.8669    0.8879    0.8769       811
# weighted avg     0.9404    0.9383    0.9392       811
