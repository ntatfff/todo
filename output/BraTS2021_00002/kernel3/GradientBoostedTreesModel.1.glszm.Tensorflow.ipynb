# %%
# Import packages and modules
import numpy  as np
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow_decision_forests as tfdf

from sklearn.model_selection import train_test_split
# Out:
# 2026-08-13 04:20:45.520165: I tensorflow/core/util/port.cc:113] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2026-08-13 04:20:45.876114: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2026-08-13 04:20:50.862005: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
# Check the version of TensorFlow Decision Forests
print("Found TensorFlow Decision Forests v" + tfdf.__version__)
# Out:
# Found TensorFlow Decision Forests v1.9.1

# %%
datasetPath = 'dataset/firstorder/kernel5/dataset.csv'

# %%
# Parameters
datasetPath = "dataset/glszm/kernel3/1.dataset.csv"

# %%
# train/validation/test = 70/10/20
dataset = pd.read_csv(datasetPath)

train_data, temp_data = train_test_split(dataset, test_size=0.3, random_state=42)
validation_data, test_data = train_test_split(temp_data, test_size=2/3, random_state=42)

# %%
from sklearn.utils.class_weight import compute_class_weight

# tinh class weight tren tap train
classes = np.array([0, 1])
weights = compute_class_weight(class_weight="balanced", classes=classes, y=train_data["label"])
class_weight = {0: weights[0], 1: weights[1]}

# gan sample_weight cho tung dong
train_data["sample_weight"] = train_data["label"].map(class_weight)
validation_data["sample_weight"] = validation_data["label"].map(class_weight)
test_data["sample_weight"] = test_data["label"].map(class_weight)

# Convert the dataset into a TensorFlow dataset.
train_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    train_data, label="label", weight="sample_weight"
)         
val_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    validation_data, label="label", weight="sample_weight"
)
test_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    test_data, label="label", weight="sample_weight"
)
# Out:
# 2026-08-13 04:21:05.000221: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:984] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2026-08-13 04:21:05.001795: W tensorflow/core/common_runtime/gpu/gpu_device.cc:2251] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...

# %%
import keras

# %%
# %%time

# Train a Gradient Boosted Trees model.
model = tfdf.keras.GradientBoostedTreesModel()

# Add evaluation metrics
model.compile(
    metrics=["accuracy"]
)
model.fit(x=train_ds)

# # Train a Gradient Boosted Trees model.
# model = tfdf.keras.GradientBoostedTreesModel(num_trees=1500)
# model.fit(train_ds)
# Out:
# Use /tmp/tmp6ssin6iu as temporary training directory
# Reading training dataset...
# [WARNING 26-08-13 04:21:05.1569 UTC gradient_boosted_trees.cc:1840] "goss_alpha" set but "sampling_method" not equal to "GOSS".
# [WARNING 26-08-13 04:21:05.1572 UTC gradient_boosted_trees.cc:1851] "goss_beta" set but "sampling_method" not equal to "GOSS".
# [WARNING 26-08-13 04:21:05.1572 UTC gradient_boosted_trees.cc:1865] "selective_gradient_boosting_ratio" set but "sampling_method" not equal to "SELGB".
# Training dataset read in 0:00:02.662376. Found 2835 examples.
# Training model...
# Model trained in 0:00:00.354380
# Compiling model...
# [INFO 26-08-13 04:21:08.2052 UTC kernel.cc:1233] Loading model from path /tmp/tmp6ssin6iu/model/ with prefix 1552f4f1cf114285
# [INFO 26-08-13 04:21:08.2078 UTC quick_scorer_extended.cc:911] The binary was compiled without AVX2 support, but your CPU supports it. Enable it for faster model inference.
# [INFO 26-08-13 04:21:08.2080 UTC abstract_model.cc:1362] Engine "GradientBoostedTreesQuickScorerExtended" built
# [INFO 26-08-13 04:21:08.2080 UTC kernel.cc:1061] Use fast generic engine
# Model compiled.
# CPU times: user 6.27 s, sys: 412 ms, total: 6.68 s
# Wall time: 6.22 s

# %%
# Evaluate the model
evaluate = model.evaluate(val_ds, return_dict=True)
print()

for name, value in evaluate.items():
    print(f"{name}: {value:.4f}")
# Out:
# WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 1/1 [==============================] - ETA: 0s - loss: 0.0000e+00 - accuracy: 0.9556
# 1/1 [==============================] - 3s 3s/step - loss: 0.0000e+00 - accuracy: 0.9556
# loss: 0.0000
# accuracy: 0.9556

# %%
# Model Summary
model.summary()
# Out:
# Model: "gradient_boosted_trees_model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
# =================================================================
# Total params: 1 (1.00 Byte)
# Trainable params: 0 (0.00 Byte)
# Non-trainable params: 1 (1.00 Byte)
# _________________________________________________________________
# Type: "GRADIENT_BOOSTED_TREES"
# Task: CLASSIFICATION
# Label: "__LABEL"
#
# Input Features (16):
# 	GrayLevelNonUniformity
# 	GrayLevelNonUniformityNormalized
# 	GrayLevelVariance
# 	HighGrayLevelZoneEmphasis
# 	LargeAreaEmphasis
# 	LargeAreaHighGrayLevelEmphasis
# 	LargeAreaLowGrayLevelEmphasis
# 	LowGrayLevelZoneEmphasis
# 	SizeZoneNonUniformity
# 	SizeZoneNonUniformityNormalized
# 	SmallAreaEmphasis
# 	SmallAreaHighGrayLevelEmphasis
# 	SmallAreaLowGrayLevelEmphasis
# 	ZoneEntropy
# 	ZonePercentage
# 	ZoneVariance
#
# Trained with weights
#
# Variable Importance: INV_MEAN_MIN_DEPTH:
#     1.        "HighGrayLevelZoneEmphasis"  1.000000 ################
#     2.           "GrayLevelNonUniformity"  0.265748 #
#     3.   "LargeAreaHighGrayLevelEmphasis"  0.217588
#     4.         "LowGrayLevelZoneEmphasis"  0.208501
#     5.    "LargeAreaLowGrayLevelEmphasis"  0.188204
#     6.                "GrayLevelVariance"  0.186192
#     7.    "SmallAreaLowGrayLevelEmphasis"  0.185489
#     8. "GrayLevelNonUniformityNormalized"  0.184774
#     9.                      "ZoneEntropy"  0.182189
#    10.   "SmallAreaHighGrayLevelEmphasis"  0.180431
#    11.                "SmallAreaEmphasis"  0.179592
#    12.            "SizeZoneNonUniformity"  0.175626
#    13.  "SizeZoneNonUniformityNormalized"  0.174611
#    14.                   "ZonePercentage"  0.172883
#    15.                "LargeAreaEmphasis"  0.172765
#    16.                     "ZoneVariance"  0.172638
#
# Variable Importance: NUM_AS_ROOT:
#     1. "HighGrayLevelZoneEmphasis" 32.000000
#
# Variable Importance: NUM_NODES:
#     1.           "GrayLevelNonUniformity" 147.000000 ################
#     2.        "HighGrayLevelZoneEmphasis" 107.000000 ###########
#     3.   "LargeAreaHighGrayLevelEmphasis" 101.000000 ##########
#     4.         "LowGrayLevelZoneEmphasis" 83.000000 ########
#     5.    "LargeAreaLowGrayLevelEmphasis" 71.000000 ######
#     6.    "SmallAreaLowGrayLevelEmphasis" 61.000000 #####
#     7.   "SmallAreaHighGrayLevelEmphasis" 44.000000 ###
#     8.                      "ZoneEntropy" 38.000000 ###
#     9. "GrayLevelNonUniformityNormalized" 33.000000 ##
#    10.                "GrayLevelVariance" 31.000000 ##
#    11.                "SmallAreaEmphasis" 29.000000 ##
#    12.            "SizeZoneNonUniformity" 27.000000 #
#    13.                "LargeAreaEmphasis" 17.000000
#    14.                   "ZonePercentage" 13.000000
#    15.  "SizeZoneNonUniformityNormalized" 12.000000
#    16.                     "ZoneVariance" 12.000000
#
# Variable Importance: SUM_SCORE:
#     1.        "HighGrayLevelZoneEmphasis" 2142.533122 ################
#     2.           "GrayLevelNonUniformity" 379.693122 ##
#     3.         "LowGrayLevelZoneEmphasis" 182.352314 #
#     4.    "LargeAreaLowGrayLevelEmphasis" 143.908891 #
#     5.   "LargeAreaHighGrayLevelEmphasis" 121.449238
#     6. "GrayLevelNonUniformityNormalized" 53.894814
#     7.                      "ZoneEntropy" 48.212999
#     8.    "SmallAreaLowGrayLevelEmphasis" 40.612957
#     9.   "SmallAreaHighGrayLevelEmphasis" 32.380502
#    10.                "SmallAreaEmphasis" 28.938268
#    11.                "LargeAreaEmphasis" 20.925082
#    12.                "GrayLevelVariance" 17.430673
#    13.            "SizeZoneNonUniformity" 15.490167
#    14.                     "ZoneVariance" 13.011237
#    15.  "SizeZoneNonUniformityNormalized" 11.448787
#    16.                   "ZonePercentage"  4.885633
#
#
#
# Loss: BINOMIAL_LOG_LIKELIHOOD
# Validation loss value: 0.495622
# Number of trees per iteration: 1
# Node format: NOT_SET
# Number of trees: 32
# Total number of nodes: 1684
#
# Number of nodes by tree:
# Count: 32 Average: 52.625 StdDev: 6.13265
# Min: 33 Max: 61 Ignored: 0
# ----------------------------------------------
# [ 33, 34) 1   3.12%   3.12% #
# [ 34, 35) 0   0.00%   3.12%
# [ 35, 37) 0   0.00%   3.12%
# [ 37, 38) 1   3.12%   6.25% #
# [ 38, 40) 0   0.00%   6.25%
# [ 40, 41) 0   0.00%   6.25%
# [ 41, 43) 0   0.00%   6.25%
# [ 43, 44) 1   3.12%   9.38% #
# [ 44, 46) 1   3.12%  12.50% #
# [ 46, 47) 0   0.00%  12.50%
# [ 47, 48) 0   0.00%  12.50%
# [ 48, 50) 4  12.50%  25.00% #####
# [ 50, 51) 0   0.00%  25.00%
# [ 51, 53) 3   9.38%  34.38% ####
# [ 53, 54) 5  15.62%  50.00% ######
# [ 54, 56) 5  15.62%  65.62% ######
# [ 56, 57) 0   0.00%  65.62%
# [ 57, 59) 8  25.00%  90.62% ##########
# [ 59, 60) 1   3.12%  93.75% #
# [ 60, 61] 2   6.25% 100.00% ###
#
# Depth by leafs:
# Count: 858 Average: 4.83916 StdDev: 0.44224
# Min: 2 Max: 5 Ignored: 0
# ----------------------------------------------
# [ 2, 3)   2   0.23%   0.23%
# [ 3, 4)  20   2.33%   2.56%
# [ 4, 5)  92  10.72%  13.29% #
# [ 5, 5] 744  86.71% 100.00% ##########
#
# Number of training obs by leaf:
# Count: 858 Average: 95.8135 StdDev: 220.751
# Min: 5 Max: 1426 Ignored: 0
# ----------------------------------------------
# [    5,   76) 663  77.27%  77.27% ##########
# [   76,  147)  65   7.58%  84.85% #
# [  147,  218)  42   4.90%  89.74% #
# [  218,  289)  16   1.86%  91.61%
# [  289,  360)   8   0.93%  92.54%
# [  360,  431)   9   1.05%  93.59%
# [  431,  502)  10   1.17%  94.76%
# [  502,  573)   7   0.82%  95.57%
# [  573,  644)   6   0.70%  96.27%
# [  644,  716)   2   0.23%  96.50%
# [  716,  787)   2   0.23%  96.74%
# [  787,  858)   1   0.12%  96.85%
# [  858,  929)   5   0.58%  97.44%
# [  929, 1000)   2   0.23%  97.67%
# [ 1000, 1071)   5   0.58%  98.25%
# [ 1071, 1142)   1   0.12%  98.37%
# [ 1142, 1213)   6   0.70%  99.07%
# [ 1213, 1284)   3   0.35%  99.42%
# [ 1284, 1355)   0   0.00%  99.42%
# [ 1355, 1426]   5   0.58% 100.00%
#
# Attribute in nodes:
# 	147 : GrayLevelNonUniformity [NUMERICAL]
# 	107 : HighGrayLevelZoneEmphasis [NUMERICAL]
# 	101 : LargeAreaHighGrayLevelEmphasis [NUMERICAL]
# 	83 : LowGrayLevelZoneEmphasis [NUMERICAL]
# 	71 : LargeAreaLowGrayLevelEmphasis [NUMERICAL]
# 	61 : SmallAreaLowGrayLevelEmphasis [NUMERICAL]
# 	44 : SmallAreaHighGrayLevelEmphasis [NUMERICAL]
# 	38 : ZoneEntropy [NUMERICAL]
# 	33 : GrayLevelNonUniformityNormalized [NUMERICAL]
# 	31 : GrayLevelVariance [NUMERICAL]
# 	29 : SmallAreaEmphasis [NUMERICAL]
# 	27 : SizeZoneNonUniformity [NUMERICAL]
# 	17 : LargeAreaEmphasis [NUMERICAL]
# 	13 : ZonePercentage [NUMERICAL]
# 	12 : ZoneVariance [NUMERICAL]
# 	12 : SizeZoneNonUniformityNormalized [NUMERICAL]
#
# Attribute in nodes with depth <= 0:
# 	32 : HighGrayLevelZoneEmphasis [NUMERICAL]
#
# Attribute in nodes with depth <= 1:
# 	45 : HighGrayLevelZoneEmphasis [NUMERICAL]
# 	15 : LowGrayLevelZoneEmphasis [NUMERICAL]
# 	15 : GrayLevelNonUniformity [NUMERICAL]
# 	10 : LargeAreaHighGrayLevelEmphasis [NUMERICAL]
# 	5 : SmallAreaLowGrayLevelEmphasis [NUMERICAL]
# 	4 : GrayLevelVariance [NUMERICAL]
# 	2 : SmallAreaEmphasis [NUMERICAL]
#
# Attribute in nodes with depth <= 2:
# 	56 : HighGrayLevelZoneEmphasis [NUMERICAL]
# 	56 : GrayLevelNonUniformity [NUMERICAL]
# 	26 : LowGrayLevelZoneEmphasis [NUMERICAL]
# 	17 : LargeAreaHighGrayLevelEmphasis [NUMERICAL]
# 	13 : GrayLevelNonUniformityNormalized [NUMERICAL]
# 	11 : SmallAreaLowGrayLevelEmphasis [NUMERICAL]
# 	10 : GrayLevelVariance [NUMERICAL]
# 	9 : ZoneEntropy [NUMERICAL]
# 	9 : LargeAreaLowGrayLevelEmphasis [NUMERICAL]
# 	6 : SmallAreaHighGrayLevelEmphasis [NUMERICAL]
# 	4 : SmallAreaEmphasis [NUMERICAL]
# 	2 : SizeZoneNonUniformityNormalized [NUMERICAL]
# 	2 : SizeZoneNonUniformity [NUMERICAL]
# 	1 : ZonePercentage [NUMERICAL]
#
# Attribute in nodes with depth <= 3:
# 	89 : GrayLevelNonUniformity [NUMERICAL]
# 	79 : HighGrayLevelZoneEmphasis [NUMERICAL]
# 	59 : LargeAreaHighGrayLevelEmphasis [NUMERICAL]
# 	42 : LowGrayLevelZoneEmphasis [NUMERICAL]
# 	37 : LargeAreaLowGrayLevelEmphasis [NUMERICAL]
# 	28 : SmallAreaLowGrayLevelEmphasis [NUMERICAL]
# 	22 : SmallAreaHighGrayLevelEmphasis [NUMERICAL]
# 	21 : GrayLevelNonUniformityNormalized [NUMERICAL]
# 	20 : ZoneEntropy [NUMERICAL]
# 	19 : GrayLevelVariance [NUMERICAL]
# 	15 : SmallAreaEmphasis [NUMERICAL]
# 	12 : SizeZoneNonUniformity [NUMERICAL]
# 	7 : SizeZoneNonUniformityNormalized [NUMERICAL]
# 	3 : ZonePercentage [NUMERICAL]
# 	1 : ZoneVariance [NUMERICAL]
#
# Attribute in nodes with depth <= 5:
# 	147 : GrayLevelNonUniformity [NUMERICAL]
# 	107 : HighGrayLevelZoneEmphasis [NUMERICAL]
# 	101 : LargeAreaHighGrayLevelEmphasis [NUMERICAL]
# 	83 : LowGrayLevelZoneEmphasis [NUMERICAL]
# 	71 : LargeAreaLowGrayLevelEmphasis [NUMERICAL]
# 	61 : SmallAreaLowGrayLevelEmphasis [NUMERICAL]
# 	44 : SmallAreaHighGrayLevelEmphasis [NUMERICAL]
# 	38 : ZoneEntropy [NUMERICAL]
# 	33 : GrayLevelNonUniformityNormalized [NUMERICAL]
# 	31 : GrayLevelVariance [NUMERICAL]
# 	29 : SmallAreaEmphasis [NUMERICAL]
# 	27 : SizeZoneNonUniformity [NUMERICAL]
# 	17 : LargeAreaEmphasis [NUMERICAL]
# 	13 : ZonePercentage [NUMERICAL]
# 	12 : ZoneVariance [NUMERICAL]
# 	12 : SizeZoneNonUniformityNormalized [NUMERICAL]
#
# Condition type in nodes:
# 	826 : HigherCondition
# Condition type in nodes with depth <= 0:
# 	32 : HigherCondition
# Condition type in nodes with depth <= 1:
# 	96 : HigherCondition
# Condition type in nodes with depth <= 2:
# 	222 : HigherCondition
# Condition type in nodes with depth <= 3:
# 	454 : HigherCondition
# Condition type in nodes with depth <= 5:
# 	826 : HigherCondition
#
# Training logs:
# Number of iteration to final model: 32
# 	Iter:1 train-loss:1.225510 valid-loss:1.240979  train-accuracy:0.948911 valid-accuracy:0.895630
# 	Iter:2 train-loss:1.091676 valid-loss:1.123044  train-accuracy:0.958549 valid-accuracy:0.906223
# 	Iter:3 train-loss:0.981047 valid-loss:1.024787  train-accuracy:0.960033 valid-accuracy:0.906223
# 	Iter:4 train-loss:0.887285 valid-loss:0.943361  train-accuracy:0.960650 valid-accuracy:0.921053
# 	Iter:5 train-loss:0.804594 valid-loss:0.875955  train-accuracy:0.961801 valid-accuracy:0.908341
# 	Iter:6 train-loss:0.735834 valid-loss:0.817135  train-accuracy:0.965220 valid-accuracy:0.923171
# 	Iter:16 train-loss:0.336860 valid-loss:0.557692  train-accuracy:0.976390 valid-accuracy:0.907448
# 	Iter:26 train-loss:0.192895 valid-loss:0.505781  train-accuracy:0.985471 valid-accuracy:0.898081
# 	Iter:36 train-loss:0.129088 valid-loss:0.497911  train-accuracy:0.989626 valid-accuracy:0.902318
# 	Iter:46 train-loss:0.097730 valid-loss:0.527676  train-accuracy:0.992783 valid-accuracy:0.888714
# 	Iter:56 train-loss:0.076735 valid-loss:0.550098  train-accuracy:0.995264 valid-accuracy:0.888714

# %%
# Model features
model.make_inspector().features()
# Out:
# ["GrayLevelNonUniformity" (1; #0),
#  "GrayLevelNonUniformityNormalized" (1; #1),
#  "GrayLevelVariance" (1; #2),
#  "HighGrayLevelZoneEmphasis" (1; #3),
#  "LargeAreaEmphasis" (1; #4),
#  "LargeAreaHighGrayLevelEmphasis" (1; #5),
#  "LargeAreaLowGrayLevelEmphasis" (1; #6),
#  "LowGrayLevelZoneEmphasis" (1; #7),
#  "SizeZoneNonUniformity" (1; #8),
#  "SizeZoneNonUniformityNormalized" (1; #9),
#  "SmallAreaEmphasis" (1; #10),
#  "SmallAreaHighGrayLevelEmphasis" (1; #11),
#  "SmallAreaLowGrayLevelEmphasis" (1; #12),
#  "ZoneEntropy" (1; #13),
#  "ZonePercentage" (1; #14),
#  "ZoneVariance" (1; #15)]

# %%
# Feature importance
model.make_inspector().variable_importances()
# Out:
# {'INV_MEAN_MIN_DEPTH': [("HighGrayLevelZoneEmphasis" (1; #3), 1.0),
#   ("GrayLevelNonUniformity" (1; #0), 0.2657482611509772),
#   ("LargeAreaHighGrayLevelEmphasis" (1; #5), 0.21758758659921582),
#   ("LowGrayLevelZoneEmphasis" (1; #7), 0.20850069161987458),
#   ("LargeAreaLowGrayLevelEmphasis" (1; #6), 0.18820431513068656),
#   ("GrayLevelVariance" (1; #2), 0.18619185999650525),
#   ("SmallAreaLowGrayLevelEmphasis" (1; #12), 0.18548855871391565),
#   ("GrayLevelNonUniformityNormalized" (1; #1), 0.18477382063391942),
#   ("ZoneEntropy" (1; #13), 0.18218924192319813),
#   ("SmallAreaHighGrayLevelEmphasis" (1; #11), 0.1804306213579416),
#   ("SmallAreaEmphasis" (1; #10), 0.17959225453851657),
#   ("SizeZoneNonUniformity" (1; #8), 0.17562603675130065),
#   ("SizeZoneNonUniformityNormalized" (1; #9), 0.17461145298155453),
#   ("ZonePercentage" (1; #14), 0.17288324155562268),
#   ("LargeAreaEmphasis" (1; #4), 0.1727647152831906),
#   ("ZoneVariance" (1; #15), 0.17263811807143037)],
#  'SUM_SCORE': [("HighGrayLevelZoneEmphasis" (1; #3), 2142.5331224669235),
#   ("GrayLevelNonUniformity" (1; #0), 379.6931224725606),
#   ("LowGrayLevelZoneEmphasis" (1; #7), 182.3523138316933),
#   ("LargeAreaLowGrayLevelEmphasis" (1; #6), 143.9088907868683),
#   ("LargeAreaHighGrayLevelEmphasis" (1; #5), 121.44923820309519),
#   ("GrayLevelNonUniformityNormalized" (1; #1), 53.89481398471407),
#   ("ZoneEntropy" (1; #13), 48.21299896026943),
#   ("SmallAreaLowGrayLevelEmphasis" (1; #12), 40.6129570930938),
#   ("SmallAreaHighGrayLevelEmphasis" (1; #11), 32.380502257853244),
#   ("SmallAreaEmphasis" (1; #10), 28.938268446799434),
#   ("LargeAreaEmphasis" (1; #4), 20.925081739701117),
#   ("GrayLevelVariance" (1; #2), 17.43067311590612),
#   ("SizeZoneNonUniformity" (1; #8), 15.490166897070331),
#   ("ZoneVariance" (1; #15), 13.011237199803048),
#   ("SizeZoneNonUniformityNormalized" (1; #9), 11.448786924491829),
#   ("ZonePercentage" (1; #14), 4.885632591784643)],
#  'NUM_AS_ROOT': [("HighGrayLevelZoneEmphasis" (1; #3), 32.0)],
#  'NUM_NODES': [("GrayLevelNonUniformity" (1; #0), 147.0),
#   ("HighGrayLevelZoneEmphasis" (1; #3), 107.0),
#   ("LargeAreaHighGrayLevelEmphasis" (1; #5), 101.0),
#   ("LowGrayLevelZoneEmphasis" (1; #7), 83.0),
#   ("LargeAreaLowGrayLevelEmphasis" (1; #6), 71.0),
#   ("SmallAreaLowGrayLevelEmphasis" (1; #12), 61.0),
#   ("SmallAreaHighGrayLevelEmphasis" (1; #11), 44.0),
#   ("ZoneEntropy" (1; #13), 38.0),
#   ("GrayLevelNonUniformityNormalized" (1; #1), 33.0),
#   ("GrayLevelVariance" (1; #2), 31.0),
#   ("SmallAreaEmphasis" (1; #10), 29.0),
#   ("SizeZoneNonUniformity" (1; #8), 27.0),
#   ("LargeAreaEmphasis" (1; #4), 17.0),
#   ("ZonePercentage" (1; #14), 13.0),
#   ("SizeZoneNonUniformityNormalized" (1; #9), 12.0),
#   ("ZoneVariance" (1; #15), 12.0)]}

# %%
# Model self evaluation
model.make_inspector().evaluation()
# Out:
# Evaluation(num_examples=None, accuracy=0.8980810642242432, loss=0.49562162160873413, rmse=None, ndcg=None, aucs=None, auuc=None, qini=None)

# %%
logs = model.make_inspector().training_logs()

plt.figure(figsize=(12, 4))
plt.subplot(1, 2, 1)
plt.plot([log.num_trees for log in logs], [log.evaluation.accuracy for log in logs])
plt.xlabel("Number of trees")
plt.ylabel("Accuracy (out-of-bag)")
plt.subplot(1, 2, 2)
plt.plot([log.num_trees for log in logs], [log.evaluation.loss for log in logs])
plt.xlabel("Number of trees")
plt.ylabel("Logloss (out-of-bag)")
plt.show()

# %% [markdown]
# Calculate the score of our hold-out validation dataset

# %%
predictions = model.predict(val_ds)
y_true      = validation_data["label"]

from sklearn.metrics import roc_auc_score
ROC_AUC = roc_auc_score(y_true, predictions)
print("The ROC AUC score is %.5f" % ROC_AUC )
# Out:
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 62ms/step
# The ROC AUC score is 0.98965

# %%
# Compute binary classification metrics with sklearn
import numpy as np
from sklearn.metrics import (
    accuracy_score,
    precision_score,
    recall_score,
    f1_score,
    roc_auc_score,
    average_precision_score,
    confusion_matrix,
    classification_report,
    matthews_corrcoef,
    log_loss,
    brier_score_loss,
)

# Get predictions (probabilities or class labels)
preds = model.predict(test_ds)
# If model outputs probabilities, convert to labels by threshold 0.5
if preds.ndim == 2:
    # For TFDF classification, preds may be class probabilities with shape (N, 2)
    if preds.shape[1] == 2:
        pos_probs = preds[:, 1]
    else:
        # If single-probability column (positive class)
        pos_probs = preds[:, -1]
    y_pred = (pos_probs >= 0.5).astype(int)
else:
    # Already class labels
    y_pred = preds.astype(int)
    pos_probs = None

# Ground truth labels (must be 0/1 integers)
y_true = test_data["label"].astype(int).to_numpy()

# Core metrics
metrics = {}
metrics["accuracy"] = accuracy_score(y_true, y_pred)
metrics["precision"] = precision_score(y_true, y_pred, zero_division=0)
metrics["recall"] = recall_score(y_true, y_pred, zero_division=0)
metrics["f1"] = f1_score(y_true, y_pred, zero_division=0)
metrics["mcc"] = matthews_corrcoef(y_true, y_pred)

# Probabilistic metrics (only if we have probabilities)
if pos_probs is not None:
    metrics["roc_auc"] = roc_auc_score(y_true, pos_probs)
    metrics["pr_auc"] = average_precision_score(y_true, pos_probs)
    metrics["log_loss"] = log_loss(y_true, pos_probs, labels=[0,1])
    metrics["brier_score"] = brier_score_loss(y_true, pos_probs)

# Confusion matrix and detailed report
cm = confusion_matrix(y_true, y_pred, labels=[0,1])
report = classification_report(y_true, y_pred, digits=4)

print("Sklearn binary metrics:")
for k, v in metrics.items():
    print(f"{k}: {v:.4f}")
print("\nConfusion matrix:\n", cm)
print("\nClassification report:\n", report)
# Out:
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 67ms/step
# Sklearn binary metrics:
# accuracy: 0.9359
# precision: 0.7431
# recall: 0.8770
# f1: 0.8045
# mcc: 0.7702
# roc_auc: 0.9760
# pr_auc: 0.9126
# log_loss: 0.1671
# brier_score: 0.0472
#
# Confusion matrix:
#  [[652  37]
#  [ 15 107]]
#
# Classification report:
#                precision    recall  f1-score   support
#
#            0     0.9775    0.9463    0.9617       689
#            1     0.7431    0.8770    0.8045       122
#
#     accuracy                         0.9359       811
#    macro avg     0.8603    0.9117    0.8831       811
# weighted avg     0.9422    0.9359    0.9380       811
