# %%
# Import packages and modules
import numpy  as np
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow_decision_forests as tfdf

from sklearn.model_selection import train_test_split
# Out:
# 2026-08-13 04:18:52.107572: I tensorflow/core/util/port.cc:113] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2026-08-13 04:18:52.494548: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2026-08-13 04:18:57.381433: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
# Check the version of TensorFlow Decision Forests
print("Found TensorFlow Decision Forests v" + tfdf.__version__)
# Out:
# Found TensorFlow Decision Forests v1.9.1

# %%
datasetPath = 'dataset/firstorder/kernel5/dataset.csv'

# %%
# Parameters
datasetPath = "dataset/glcm/kernel3/1.dataset.csv"

# %%
# train/validation/test = 70/10/20
dataset = pd.read_csv(datasetPath)

train_data, temp_data = train_test_split(dataset, test_size=0.3, random_state=42)
validation_data, test_data = train_test_split(temp_data, test_size=2/3, random_state=42)

# %%
from sklearn.utils.class_weight import compute_class_weight

# tinh class weight tren tap train
classes = np.array([0, 1])
weights = compute_class_weight(class_weight="balanced", classes=classes, y=train_data["label"])
class_weight = {0: weights[0], 1: weights[1]}

# gan sample_weight cho tung dong
train_data["sample_weight"] = train_data["label"].map(class_weight)
validation_data["sample_weight"] = validation_data["label"].map(class_weight)
test_data["sample_weight"] = test_data["label"].map(class_weight)

# Convert the dataset into a TensorFlow dataset.
train_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    train_data, label="label", weight="sample_weight"
)         
val_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    validation_data, label="label", weight="sample_weight"
)
test_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    test_data, label="label", weight="sample_weight"
)
# Out:
# 2026-08-13 04:19:11.603644: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:984] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2026-08-13 04:19:11.605289: W tensorflow/core/common_runtime/gpu/gpu_device.cc:2251] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...

# %%
import keras

# %%
# %%time

# Train a Gradient Boosted Trees model.
model = tfdf.keras.GradientBoostedTreesModel()

# Add evaluation metrics
model.compile(
    metrics=["accuracy"]
)
model.fit(x=train_ds)

# # Train a Gradient Boosted Trees model.
# model = tfdf.keras.GradientBoostedTreesModel(num_trees=1500)
# model.fit(train_ds)
# Out:
# Use /tmp/tmp5l3xahfb as temporary training directory
# Reading training dataset...
# [WARNING 26-08-13 04:19:11.7774 UTC gradient_boosted_trees.cc:1840] "goss_alpha" set but "sampling_method" not equal to "GOSS".
# [WARNING 26-08-13 04:19:11.7776 UTC gradient_boosted_trees.cc:1851] "goss_beta" set but "sampling_method" not equal to "GOSS".
# [WARNING 26-08-13 04:19:11.7776 UTC gradient_boosted_trees.cc:1865] "selective_gradient_boosting_ratio" set but "sampling_method" not equal to "SELGB".
# Training dataset read in 0:00:02.664502. Found 2835 examples.
# Training model...
# Model trained in 0:00:00.578228
# Compiling model...
# [INFO 26-08-13 04:19:15.0492 UTC kernel.cc:1233] Loading model from path /tmp/tmp5l3xahfb/model/ with prefix ddac70b4f06d4390
# [INFO 26-08-13 04:19:15.0525 UTC quick_scorer_extended.cc:911] The binary was compiled without AVX2 support, but your CPU supports it. Enable it for faster model inference.
# [INFO 26-08-13 04:19:15.0527 UTC abstract_model.cc:1362] Engine "GradientBoostedTreesQuickScorerExtended" built
# [INFO 26-08-13 04:19:15.0527 UTC kernel.cc:1061] Use fast generic engine
# Model compiled.
# CPU times: user 7.06 s, sys: 726 ms, total: 7.78 s
# Wall time: 6.61 s

# %%
# Evaluate the model
evaluate = model.evaluate(val_ds, return_dict=True)
print()

for name, value in evaluate.items():
    print(f"{name}: {value:.4f}")
# Out:
# WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 1/1 [==============================] - ETA: 0s - loss: 0.0000e+00 - accuracy: 0.9432
# 1/1 [==============================] - 3s 3s/step - loss: 0.0000e+00 - accuracy: 0.9432
# loss: 0.0000
# accuracy: 0.9432

# %%
# Model Summary
model.summary()
# Out:
# Model: "gradient_boosted_trees_model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
# =================================================================
# Total params: 1 (1.00 Byte)
# Trainable params: 0 (0.00 Byte)
# Non-trainable params: 1 (1.00 Byte)
# _________________________________________________________________
# Type: "GRADIENT_BOOSTED_TREES"
# Task: CLASSIFICATION
# Label: "__LABEL"
#
# Input Features (24):
# 	Autocorrelation
# 	ClusterProminence
# 	ClusterShade
# 	ClusterTendency
# 	Contrast
# 	Correlation
# 	DifferenceAverage
# 	DifferenceEntropy
# 	DifferenceVariance
# 	Id
# 	Idm
# 	Idmn
# 	Idn
# 	Imc1
# 	Imc2
# 	InverseVariance
# 	JointAverage
# 	JointEnergy
# 	JointEntropy
# 	MCC
# 	MaximumProbability
# 	SumAverage
# 	SumEntropy
# 	SumSquares
#
# Trained with weights
#
# Variable Importance: INV_MEAN_MIN_DEPTH:
#     1.    "Autocorrelation"  0.569816 ################
#     2.       "JointAverage"  0.237335 ##
#     3.        "Correlation"  0.211837 #
#     4.         "SumAverage"  0.210552 #
#     5.                "Idm"  0.198875
#     6. "MaximumProbability"  0.192061
#     7.       "ClusterShade"  0.191829
#     8.                "MCC"  0.189317
#     9.         "SumEntropy"  0.187608
#    10. "DifferenceVariance"  0.187162
#    11.               "Imc2"  0.185281
#    12.    "InverseVariance"  0.184441
#    13.        "JointEnergy"  0.184102
#    14.               "Imc1"  0.183473
#    15.  "ClusterProminence"  0.181775
#    16.                 "Id"  0.181152
#    17.       "JointEntropy"  0.180984
#    18.  "DifferenceEntropy"  0.180453
#    19.  "DifferenceAverage"  0.178118
#    20.                "Idn"  0.177789
#    21.         "SumSquares"  0.176952
#    22.               "Idmn"  0.176884
#    23.           "Contrast"  0.176648
#    24.    "ClusterTendency"  0.176593
#
# Variable Importance: NUM_AS_ROOT:
#     1. "Autocorrelation" 43.000000 ################
#     2.    "JointAverage"  9.000000 ##
#     3.      "SumAverage"  3.000000
#
# Variable Importance: NUM_NODES:
#     1.    "Autocorrelation" 201.000000 ################
#     2.        "Correlation" 140.000000 ###########
#     3. "MaximumProbability" 111.000000 ########
#     4.         "SumAverage" 82.000000 ######
#     5.       "JointAverage" 72.000000 #####
#     6.       "ClusterShade" 68.000000 #####
#     7. "DifferenceVariance" 64.000000 ####
#     8.                "Idm" 61.000000 ####
#     9.                "MCC" 58.000000 ####
#    10.    "InverseVariance" 43.000000 ###
#    11.               "Imc1" 40.000000 ##
#    12.        "JointEnergy" 40.000000 ##
#    13.         "SumEntropy" 38.000000 ##
#    14.  "ClusterProminence" 37.000000 ##
#    15.                 "Id" 32.000000 ##
#    16.               "Imc2" 28.000000 #
#    17.  "DifferenceEntropy" 27.000000 #
#    18.       "JointEntropy" 21.000000 #
#    19.                "Idn" 14.000000
#    20.  "DifferenceAverage" 11.000000
#    21.         "SumSquares"  7.000000
#    22.           "Contrast"  5.000000
#    23.               "Idmn"  5.000000
#    24.    "ClusterTendency"  4.000000
#
# Variable Importance: SUM_SCORE:
#     1.    "Autocorrelation" 2324.477259 ################
#     2.                "Idm" 150.572581 #
#     3.        "Correlation" 115.739327
#     4.       "JointAverage" 110.442610
#     5. "MaximumProbability" 92.363119
#     6.         "SumAverage" 72.493677
#     7. "DifferenceVariance" 53.550736
#     8.       "JointEntropy" 50.323419
#     9.               "Imc1" 49.171905
#    10.    "InverseVariance" 47.992076
#    11.               "Imc2" 44.414472
#    12.                "MCC" 33.936546
#    13.       "ClusterShade" 31.158743
#    14.  "ClusterProminence" 28.687617
#    15.                 "Id" 27.370318
#    16.        "JointEnergy" 26.153850
#    17.         "SumEntropy" 25.702985
#    18.                "Idn" 11.545273
#    19.  "DifferenceEntropy"  7.681376
#    20.  "DifferenceAverage"  5.865494
#    21.         "SumSquares"  1.320293
#    22.    "ClusterTendency"  1.050866
#    23.               "Idmn"  0.672095
#    24.           "Contrast"  0.458076
#
#
#
# Loss: BINOMIAL_LOG_LIKELIHOOD
# Validation loss value: 0.254891
# Number of trees per iteration: 1
# Node format: NOT_SET
# Number of trees: 55
# Total number of nodes: 2473
#
# Number of nodes by tree:
# Count: 55 Average: 44.9636 StdDev: 10.1012
# Min: 19 Max: 61 Ignored: 0
# ----------------------------------------------
# [ 19, 21) 1   1.82%   1.82% ##
# [ 21, 23) 0   0.00%   1.82%
# [ 23, 25) 1   1.82%   3.64% ##
# [ 25, 27) 0   0.00%   3.64%
# [ 27, 29) 2   3.64%   7.27% ###
# [ 29, 31) 1   1.82%   9.09% ##
# [ 31, 34) 4   7.27%  16.36% #######
# [ 34, 36) 3   5.45%  21.82% #####
# [ 36, 38) 3   5.45%  27.27% #####
# [ 38, 40) 2   3.64%  30.91% ###
# [ 40, 42) 2   3.64%  34.55% ###
# [ 42, 44) 4   7.27%  41.82% #######
# [ 44, 46) 2   3.64%  45.45% ###
# [ 46, 49) 6  10.91%  56.36% ##########
# [ 49, 51) 3   5.45%  61.82% #####
# [ 51, 53) 5   9.09%  70.91% ########
# [ 53, 55) 5   9.09%  80.00% ########
# [ 55, 57) 4   7.27%  87.27% #######
# [ 57, 59) 3   5.45%  92.73% #####
# [ 59, 61] 4   7.27% 100.00% #######
#
# Depth by leafs:
# Count: 1264 Average: 4.71598 StdDev: 0.62201
# Min: 2 Max: 5 Ignored: 0
# ----------------------------------------------
# [ 2, 3)   21   1.66%   1.66%
# [ 3, 4)   53   4.19%   5.85% #
# [ 4, 5)  190  15.03%  20.89% ##
# [ 5, 5] 1000  79.11% 100.00% ##########
#
# Number of training obs by leaf:
# Count: 1264 Average: 111.784 StdDev: 275.045
# Min: 5 Max: 1648 Ignored: 0
# ----------------------------------------------
# [    5,   87) 999  79.03%  79.03% ##########
# [   87,  169)  80   6.33%  85.36% #
# [  169,  251)  59   4.67%  90.03% #
# [  251,  333)  24   1.90%  91.93%
# [  333,  416)   8   0.63%  92.56%
# [  416,  498)   4   0.32%  92.88%
# [  498,  580)  14   1.11%  93.99%
# [  580,  662)   5   0.40%  94.38%
# [  662,  744)   8   0.63%  95.02%
# [  744,  827)   0   0.00%  95.02%
# [  827,  909)   7   0.55%  95.57%
# [  909,  991)   7   0.55%  96.12%
# [  991, 1073)   5   0.40%  96.52%
# [ 1073, 1155)  10   0.79%  97.31%
# [ 1155, 1238)  10   0.79%  98.10%
# [ 1238, 1320)   6   0.47%  98.58%
# [ 1320, 1402)   3   0.24%  98.81%
# [ 1402, 1484)   6   0.47%  99.29%
# [ 1484, 1566)   4   0.32%  99.60%
# [ 1566, 1648]   5   0.40% 100.00%
#
# Attribute in nodes:
# 	201 : Autocorrelation [NUMERICAL]
# 	140 : Correlation [NUMERICAL]
# 	111 : MaximumProbability [NUMERICAL]
# 	82 : SumAverage [NUMERICAL]
# 	72 : JointAverage [NUMERICAL]
# 	68 : ClusterShade [NUMERICAL]
# 	64 : DifferenceVariance [NUMERICAL]
# 	61 : Idm [NUMERICAL]
# 	58 : MCC [NUMERICAL]
# 	43 : InverseVariance [NUMERICAL]
# 	40 : JointEnergy [NUMERICAL]
# 	40 : Imc1 [NUMERICAL]
# 	38 : SumEntropy [NUMERICAL]
# 	37 : ClusterProminence [NUMERICAL]
# 	32 : Id [NUMERICAL]
# 	28 : Imc2 [NUMERICAL]
# 	27 : DifferenceEntropy [NUMERICAL]
# 	21 : JointEntropy [NUMERICAL]
# 	14 : Idn [NUMERICAL]
# 	11 : DifferenceAverage [NUMERICAL]
# 	7 : SumSquares [NUMERICAL]
# 	5 : Idmn [NUMERICAL]
# 	5 : Contrast [NUMERICAL]
# 	4 : ClusterTendency [NUMERICAL]
#
# Attribute in nodes with depth <= 0:
# 	43 : Autocorrelation [NUMERICAL]
# 	9 : JointAverage [NUMERICAL]
# 	3 : SumAverage [NUMERICAL]
#
# Attribute in nodes with depth <= 1:
# 	79 : Autocorrelation [NUMERICAL]
# 	27 : JointAverage [NUMERICAL]
# 	16 : SumAverage [NUMERICAL]
# 	13 : Correlation [NUMERICAL]
# 	7 : ClusterShade [NUMERICAL]
# 	6 : Idm [NUMERICAL]
# 	4 : MCC [NUMERICAL]
# 	3 : SumEntropy [NUMERICAL]
# 	2 : MaximumProbability [NUMERICAL]
# 	2 : JointEnergy [NUMERICAL]
# 	2 : InverseVariance [NUMERICAL]
# 	2 : DifferenceVariance [NUMERICAL]
# 	1 : Imc1 [NUMERICAL]
# 	1 : DifferenceEntropy [NUMERICAL]
#
# Attribute in nodes with depth <= 2:
# 	107 : Autocorrelation [NUMERICAL]
# 	38 : Correlation [NUMERICAL]
# 	33 : JointAverage [NUMERICAL]
# 	29 : Idm [NUMERICAL]
# 	24 : SumAverage [NUMERICAL]
# 	17 : MaximumProbability [NUMERICAL]
# 	16 : MCC [NUMERICAL]
# 	14 : SumEntropy [NUMERICAL]
# 	14 : Imc2 [NUMERICAL]
# 	11 : JointEnergy [NUMERICAL]
# 	11 : ClusterShade [NUMERICAL]
# 	10 : DifferenceVariance [NUMERICAL]
# 	7 : JointEntropy [NUMERICAL]
# 	7 : InverseVariance [NUMERICAL]
# 	6 : ClusterProminence [NUMERICAL]
# 	5 : Imc1 [NUMERICAL]
# 	5 : Id [NUMERICAL]
# 	5 : DifferenceEntropy [NUMERICAL]
# 	3 : Idn [NUMERICAL]
# 	2 : DifferenceAverage [NUMERICAL]
#
# Attribute in nodes with depth <= 3:
# 	143 : Autocorrelation [NUMERICAL]
# 	87 : Correlation [NUMERICAL]
# 	49 : SumAverage [NUMERICAL]
# 	49 : Idm [NUMERICAL]
# 	48 : JointAverage [NUMERICAL]
# 	42 : MaximumProbability [NUMERICAL]
# 	33 : MCC [NUMERICAL]
# 	32 : ClusterShade [NUMERICAL]
# 	30 : DifferenceVariance [NUMERICAL]
# 	26 : JointEnergy [NUMERICAL]
# 	25 : SumEntropy [NUMERICAL]
# 	22 : Imc1 [NUMERICAL]
# 	22 : ClusterProminence [NUMERICAL]
# 	21 : Imc2 [NUMERICAL]
# 	20 : InverseVariance [NUMERICAL]
# 	18 : Id [NUMERICAL]
# 	14 : DifferenceEntropy [NUMERICAL]
# 	11 : JointEntropy [NUMERICAL]
# 	5 : Idn [NUMERICAL]
# 	5 : DifferenceAverage [NUMERICAL]
# 	3 : Idmn [NUMERICAL]
# 	2 : ClusterTendency [NUMERICAL]
# 	1 : SumSquares [NUMERICAL]
# 	1 : Contrast [NUMERICAL]
#
# Attribute in nodes with depth <= 5:
# 	201 : Autocorrelation [NUMERICAL]
# 	140 : Correlation [NUMERICAL]
# 	111 : MaximumProbability [NUMERICAL]
# 	82 : SumAverage [NUMERICAL]
# 	72 : JointAverage [NUMERICAL]
# 	68 : ClusterShade [NUMERICAL]
# 	64 : DifferenceVariance [NUMERICAL]
# 	61 : Idm [NUMERICAL]
# 	58 : MCC [NUMERICAL]
# 	43 : InverseVariance [NUMERICAL]
# 	40 : JointEnergy [NUMERICAL]
# 	40 : Imc1 [NUMERICAL]
# 	38 : SumEntropy [NUMERICAL]
# 	37 : ClusterProminence [NUMERICAL]
# 	32 : Id [NUMERICAL]
# 	28 : Imc2 [NUMERICAL]
# 	27 : DifferenceEntropy [NUMERICAL]
# 	21 : JointEntropy [NUMERICAL]
# 	14 : Idn [NUMERICAL]
# 	11 : DifferenceAverage [NUMERICAL]
# 	7 : SumSquares [NUMERICAL]
# 	5 : Idmn [NUMERICAL]
# 	5 : Contrast [NUMERICAL]
# 	4 : ClusterTendency [NUMERICAL]
#
# Condition type in nodes:
# 	1209 : HigherCondition
# Condition type in nodes with depth <= 0:
# 	55 : HigherCondition
# Condition type in nodes with depth <= 1:
# 	165 : HigherCondition
# Condition type in nodes with depth <= 2:
# 	364 : HigherCondition
# Condition type in nodes with depth <= 3:
# 	709 : HigherCondition
# Condition type in nodes with depth <= 5:
# 	1209 : HigherCondition
#
# Training logs:
# Number of iteration to final model: 55
# 	Iter:1 train-loss:1.223137 valid-loss:1.223747  train-accuracy:0.953449 valid-accuracy:0.965635
# 	Iter:2 train-loss:1.088813 valid-loss:1.088514  train-accuracy:0.958906 valid-accuracy:0.973612
# 	Iter:3 train-loss:0.976161 valid-loss:0.983708  train-accuracy:0.963223 valid-accuracy:0.971618
# 	Iter:4 train-loss:0.880187 valid-loss:0.897039  train-accuracy:0.967487 valid-accuracy:0.942773
# 	Iter:5 train-loss:0.798066 valid-loss:0.817125  train-accuracy:0.967715 valid-accuracy:0.971618
# 	Iter:6 train-loss:0.725143 valid-loss:0.750730  train-accuracy:0.967540 valid-accuracy:0.944767
# 	Iter:16 train-loss:0.332974 valid-loss:0.411514  train-accuracy:0.977681 valid-accuracy:0.957195
# 	Iter:26 train-loss:0.189322 valid-loss:0.312709  train-accuracy:0.982349 valid-accuracy:0.957195
# 	Iter:36 train-loss:0.126433 valid-loss:0.274834  train-accuracy:0.990543 valid-accuracy:0.957195
# 	Iter:46 train-loss:0.099670 valid-loss:0.264581  train-accuracy:0.994754 valid-accuracy:0.944767
# 	Iter:56 train-loss:0.079876 valid-loss:0.255069  train-accuracy:0.995895 valid-accuracy:0.944767
# 	Iter:66 train-loss:0.066637 valid-loss:0.265459  train-accuracy:0.996579 valid-accuracy:0.946761
# 	Iter:76 train-loss:0.054539 valid-loss:0.273515  train-accuracy:0.997947 valid-accuracy:0.946761

# %%
# Model features
model.make_inspector().features()
# Out:
# ["Autocorrelation" (1; #0),
#  "ClusterProminence" (1; #1),
#  "ClusterShade" (1; #2),
#  "ClusterTendency" (1; #3),
#  "Contrast" (1; #4),
#  "Correlation" (1; #5),
#  "DifferenceAverage" (1; #6),
#  "DifferenceEntropy" (1; #7),
#  "DifferenceVariance" (1; #8),
#  "Id" (1; #9),
#  "Idm" (1; #10),
#  "Idmn" (1; #11),
#  "Idn" (1; #12),
#  "Imc1" (1; #13),
#  "Imc2" (1; #14),
#  "InverseVariance" (1; #15),
#  "JointAverage" (1; #16),
#  "JointEnergy" (1; #17),
#  "JointEntropy" (1; #18),
#  "MCC" (1; #19),
#  "MaximumProbability" (1; #20),
#  "SumAverage" (1; #21),
#  "SumEntropy" (1; #22),
#  "SumSquares" (1; #23)]

# %%
# Feature importance
model.make_inspector().variable_importances()
# Out:
# {'INV_MEAN_MIN_DEPTH': [("Autocorrelation" (1; #0), 0.5698157473719296),
#   ("JointAverage" (1; #16), 0.23733533389291925),
#   ("Correlation" (1; #5), 0.21183748022510734),
#   ("SumAverage" (1; #21), 0.2105518513546381),
#   ("Idm" (1; #10), 0.19887538559140533),
#   ("MaximumProbability" (1; #20), 0.19206146204844235),
#   ("ClusterShade" (1; #2), 0.19182875406813724),
#   ("MCC" (1; #19), 0.1893165404967832),
#   ("SumEntropy" (1; #22), 0.1876082674402725),
#   ("DifferenceVariance" (1; #8), 0.18716151572213205),
#   ("Imc2" (1; #14), 0.1852808592297612),
#   ("InverseVariance" (1; #15), 0.1844407962780916),
#   ("JointEnergy" (1; #17), 0.18410230658198318),
#   ("Imc1" (1; #13), 0.1834731635534331),
#   ("ClusterProminence" (1; #1), 0.18177453461393966),
#   ("Id" (1; #9), 0.18115221195763132),
#   ("JointEntropy" (1; #18), 0.1809835265644958),
#   ("DifferenceEntropy" (1; #7), 0.18045266378619496),
#   ("DifferenceAverage" (1; #6), 0.17811828098699914),
#   ("Idn" (1; #12), 0.1777886872912659),
#   ("SumSquares" (1; #23), 0.17695217341222003),
#   ("Idmn" (1; #11), 0.1768836039766153),
#   ("Contrast" (1; #4), 0.17664848898329766),
#   ("ClusterTendency" (1; #3), 0.1765929248452359)],
#  'NUM_AS_ROOT': [("Autocorrelation" (1; #0), 43.0),
#   ("JointAverage" (1; #16), 9.0),
#   ("SumAverage" (1; #21), 3.0)],
#  'SUM_SCORE': [("Autocorrelation" (1; #0), 2324.477259303369),
#   ("Idm" (1; #10), 150.57258054219284),
#   ("Correlation" (1; #5), 115.73932742797776),
#   ("JointAverage" (1; #16), 110.4426099870693),
#   ("MaximumProbability" (1; #20), 92.36311912947241),
#   ("SumAverage" (1; #21), 72.49367699136474),
#   ("DifferenceVariance" (1; #8), 53.55073554426713),
#   ("JointEntropy" (1; #18), 50.32341937116043),
#   ("Imc1" (1; #13), 49.17190518089487),
#   ("InverseVariance" (1; #15), 47.992075558176325),
#   ("Imc2" (1; #14), 44.4144724746446),
#   ("MCC" (1; #19), 33.936545867359214),
#   ("ClusterShade" (1; #2), 31.158743057240642),
#   ("ClusterProminence" (1; #1), 28.6876173041038),
#   ("Id" (1; #9), 27.370317532087395),
#   ("JointEnergy" (1; #17), 26.153849539897408),
#   ("SumEntropy" (1; #22), 25.70298533297171),
#   ("Idn" (1; #12), 11.545272500126721),
#   ("DifferenceEntropy" (1; #7), 7.68137574577214),
#   ("DifferenceAverage" (1; #6), 5.865494270683377),
#   ("SumSquares" (1; #23), 1.3202932881616976),
#   ("ClusterTendency" (1; #3), 1.0508663398508609),
#   ("Idmn" (1; #11), 0.6720954409374776),
#   ("Contrast" (1; #4), 0.45807565421459706)],
#  'NUM_NODES': [("Autocorrelation" (1; #0), 201.0),
#   ("Correlation" (1; #5), 140.0),
#   ("MaximumProbability" (1; #20), 111.0),
#   ("SumAverage" (1; #21), 82.0),
#   ("JointAverage" (1; #16), 72.0),
#   ("ClusterShade" (1; #2), 68.0),
#   ("DifferenceVariance" (1; #8), 64.0),
#   ("Idm" (1; #10), 61.0),
#   ("MCC" (1; #19), 58.0),
#   ("InverseVariance" (1; #15), 43.0),
#   ("Imc1" (1; #13), 40.0),
#   ("JointEnergy" (1; #17), 40.0),
#   ("SumEntropy" (1; #22), 38.0),
#   ("ClusterProminence" (1; #1), 37.0),
#   ("Id" (1; #9), 32.0),
#   ("Imc2" (1; #14), 28.0),
#   ("DifferenceEntropy" (1; #7), 27.0),
#   ("JointEntropy" (1; #18), 21.0),
#   ("Idn" (1; #12), 14.0),
#   ("DifferenceAverage" (1; #6), 11.0),
#   ("SumSquares" (1; #23), 7.0),
#   ("Contrast" (1; #4), 5.0),
#   ("Idmn" (1; #11), 5.0),
#   ("ClusterTendency" (1; #3), 4.0)]}

# %%
# Model self evaluation
model.make_inspector().evaluation()
# Out:
# Evaluation(num_examples=None, accuracy=0.9447669386863708, loss=0.2548907995223999, rmse=None, ndcg=None, aucs=None, auuc=None, qini=None)

# %%
logs = model.make_inspector().training_logs()

plt.figure(figsize=(12, 4))
plt.subplot(1, 2, 1)
plt.plot([log.num_trees for log in logs], [log.evaluation.accuracy for log in logs])
plt.xlabel("Number of trees")
plt.ylabel("Accuracy (out-of-bag)")
plt.subplot(1, 2, 2)
plt.plot([log.num_trees for log in logs], [log.evaluation.loss for log in logs])
plt.xlabel("Number of trees")
plt.ylabel("Logloss (out-of-bag)")
plt.show()

# %% [markdown]
# Calculate the score of our hold-out validation dataset

# %%
predictions = model.predict(val_ds)
y_true      = validation_data["label"]

from sklearn.metrics import roc_auc_score
ROC_AUC = roc_auc_score(y_true, predictions)
print("The ROC AUC score is %.5f" % ROC_AUC )
# Out:
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 66ms/step
# The ROC AUC score is 0.95307

# %%
# Compute binary classification metrics with sklearn
import numpy as np
from sklearn.metrics import (
    accuracy_score,
    precision_score,
    recall_score,
    f1_score,
    roc_auc_score,
    average_precision_score,
    confusion_matrix,
    classification_report,
    matthews_corrcoef,
    log_loss,
    brier_score_loss,
)

# Get predictions (probabilities or class labels)
preds = model.predict(test_ds)
# If model outputs probabilities, convert to labels by threshold 0.5
if preds.ndim == 2:
    # For TFDF classification, preds may be class probabilities with shape (N, 2)
    if preds.shape[1] == 2:
        pos_probs = preds[:, 1]
    else:
        # If single-probability column (positive class)
        pos_probs = preds[:, -1]
    y_pred = (pos_probs >= 0.5).astype(int)
else:
    # Already class labels
    y_pred = preds.astype(int)
    pos_probs = None

# Ground truth labels (must be 0/1 integers)
y_true = test_data["label"].astype(int).to_numpy()

# Core metrics
metrics = {}
metrics["accuracy"] = accuracy_score(y_true, y_pred)
metrics["precision"] = precision_score(y_true, y_pred, zero_division=0)
metrics["recall"] = recall_score(y_true, y_pred, zero_division=0)
metrics["f1"] = f1_score(y_true, y_pred, zero_division=0)
metrics["mcc"] = matthews_corrcoef(y_true, y_pred)

# Probabilistic metrics (only if we have probabilities)
if pos_probs is not None:
    metrics["roc_auc"] = roc_auc_score(y_true, pos_probs)
    metrics["pr_auc"] = average_precision_score(y_true, pos_probs)
    metrics["log_loss"] = log_loss(y_true, pos_probs, labels=[0,1])
    metrics["brier_score"] = brier_score_loss(y_true, pos_probs)

# Confusion matrix and detailed report
cm = confusion_matrix(y_true, y_pred, labels=[0,1])
report = classification_report(y_true, y_pred, digits=4)

print("Sklearn binary metrics:")
for k, v in metrics.items():
    print(f"{k}: {v:.4f}")
print("\nConfusion matrix:\n", cm)
print("\nClassification report:\n", report)
# Out:
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 77ms/step
# Sklearn binary metrics:
# accuracy: 0.9704
# precision: 0.8548
# recall: 0.9464
# f1: 0.8983
# mcc: 0.8826
# roc_auc: 0.9889
# pr_auc: 0.9661
# log_loss: 0.0899
# brier_score: 0.0239
#
# Confusion matrix:
#  [[681  18]
#  [  6 106]]
#
# Classification report:
#                precision    recall  f1-score   support
#
#            0     0.9913    0.9742    0.9827       699
#            1     0.8548    0.9464    0.8983       112
#
#     accuracy                         0.9704       811
#    macro avg     0.9231    0.9603    0.9405       811
# weighted avg     0.9724    0.9704    0.9710       811
