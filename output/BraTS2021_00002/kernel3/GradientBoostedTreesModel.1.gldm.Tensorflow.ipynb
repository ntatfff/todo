# %%
# Import packages and modules
import numpy  as np
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow_decision_forests as tfdf

from sklearn.model_selection import train_test_split
# Out:
# 2026-08-13 04:19:29.816354: I tensorflow/core/util/port.cc:113] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2026-08-13 04:19:30.183156: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2026-08-13 04:19:35.811084: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
# Check the version of TensorFlow Decision Forests
print("Found TensorFlow Decision Forests v" + tfdf.__version__)
# Out:
# Found TensorFlow Decision Forests v1.9.1

# %%
datasetPath = 'dataset/firstorder/kernel5/dataset.csv'

# %%
# Parameters
datasetPath = "dataset/gldm/kernel3/1.dataset.csv"

# %%
# train/validation/test = 70/10/20
dataset = pd.read_csv(datasetPath)

train_data, temp_data = train_test_split(dataset, test_size=0.3, random_state=42)
validation_data, test_data = train_test_split(temp_data, test_size=2/3, random_state=42)

# %%
from sklearn.utils.class_weight import compute_class_weight

# tinh class weight tren tap train
classes = np.array([0, 1])
weights = compute_class_weight(class_weight="balanced", classes=classes, y=train_data["label"])
class_weight = {0: weights[0], 1: weights[1]}

# gan sample_weight cho tung dong
train_data["sample_weight"] = train_data["label"].map(class_weight)
validation_data["sample_weight"] = validation_data["label"].map(class_weight)
test_data["sample_weight"] = test_data["label"].map(class_weight)

# Convert the dataset into a TensorFlow dataset.
train_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    train_data, label="label", weight="sample_weight"
)         
val_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    validation_data, label="label", weight="sample_weight"
)
test_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    test_data, label="label", weight="sample_weight"
)
# Out:
# 2026-08-13 04:19:49.463497: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:984] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2026-08-13 04:19:49.465647: W tensorflow/core/common_runtime/gpu/gpu_device.cc:2251] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...

# %%
import keras

# %%
# %%time

# Train a Gradient Boosted Trees model.
model = tfdf.keras.GradientBoostedTreesModel()

# Add evaluation metrics
model.compile(
    metrics=["accuracy"]
)
model.fit(x=train_ds)

# # Train a Gradient Boosted Trees model.
# model = tfdf.keras.GradientBoostedTreesModel(num_trees=1500)
# model.fit(train_ds)
# Out:
# Use /tmp/tmp_mq2nzet as temporary training directory
# Reading training dataset...
# [WARNING 26-08-13 04:19:49.6193 UTC gradient_boosted_trees.cc:1840] "goss_alpha" set but "sampling_method" not equal to "GOSS".
# [WARNING 26-08-13 04:19:49.6197 UTC gradient_boosted_trees.cc:1851] "goss_beta" set but "sampling_method" not equal to "GOSS".
# [WARNING 26-08-13 04:19:49.6197 UTC gradient_boosted_trees.cc:1865] "selective_gradient_boosting_ratio" set but "sampling_method" not equal to "SELGB".
# Training dataset read in 0:00:02.715953. Found 2835 examples.
# Training model...
# Model trained in 0:00:00.316713
# Compiling model...
# [INFO 26-08-13 04:19:52.6887 UTC kernel.cc:1233] Loading model from path /tmp/tmp_mq2nzet/model/ with prefix 838dacf4c20b4402
# [INFO 26-08-13 04:19:52.6911 UTC quick_scorer_extended.cc:911] The binary was compiled without AVX2 support, but your CPU supports it. Enable it for faster model inference.
# [INFO 26-08-13 04:19:52.6912 UTC abstract_model.cc:1362] Engine "GradientBoostedTreesQuickScorerExtended" built
# [INFO 26-08-13 04:19:52.6912 UTC kernel.cc:1061] Use fast generic engine
# Model compiled.
# CPU times: user 6.06 s, sys: 385 ms, total: 6.45 s
# Wall time: 6.14 s

# %%
# Evaluate the model
evaluate = model.evaluate(val_ds, return_dict=True)
print()

for name, value in evaluate.items():
    print(f"{name}: {value:.4f}")
# Out:
# WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 1/1 [==============================] - ETA: 0s - loss: 0.0000e+00 - accuracy: 0.9630
# 1/1 [==============================] - 3s 3s/step - loss: 0.0000e+00 - accuracy: 0.9630
# loss: 0.0000
# accuracy: 0.9630

# %%
# Model Summary
model.summary()
# Out:
# Model: "gradient_boosted_trees_model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
# =================================================================
# Total params: 1 (1.00 Byte)
# Trainable params: 0 (0.00 Byte)
# Non-trainable params: 1 (1.00 Byte)
# _________________________________________________________________
# Type: "GRADIENT_BOOSTED_TREES"
# Task: CLASSIFICATION
# Label: "__LABEL"
#
# Input Features (14):
# 	DependenceEntropy
# 	DependenceNonUniformity
# 	DependenceNonUniformityNormalized
# 	DependenceVariance
# 	GrayLevelNonUniformity
# 	GrayLevelVariance
# 	HighGrayLevelEmphasis
# 	LargeDependenceEmphasis
# 	LargeDependenceHighGrayLevelEmphasis
# 	LargeDependenceLowGrayLevelEmphasis
# 	LowGrayLevelEmphasis
# 	SmallDependenceEmphasis
# 	SmallDependenceHighGrayLevelEmphasis
# 	SmallDependenceLowGrayLevelEmphasis
#
# Trained with weights
#
# Variable Importance: INV_MEAN_MIN_DEPTH:
#     1.                "HighGrayLevelEmphasis"  0.586638 ################
#     2.                 "LowGrayLevelEmphasis"  0.284600 ####
#     3. "LargeDependenceHighGrayLevelEmphasis"  0.241106 ##
#     4.  "SmallDependenceLowGrayLevelEmphasis"  0.208845 #
#     5.                    "DependenceEntropy"  0.197939
#     6.                    "GrayLevelVariance"  0.188567
#     7.               "GrayLevelNonUniformity"  0.187350
#     8. "SmallDependenceHighGrayLevelEmphasis"  0.186608
#     9.              "SmallDependenceEmphasis"  0.185355
#    10.  "LargeDependenceLowGrayLevelEmphasis"  0.177660
#    11.                   "DependenceVariance"  0.176951
#    12.    "DependenceNonUniformityNormalized"  0.174895
#    13.              "LargeDependenceEmphasis"  0.174546
#    14.              "DependenceNonUniformity"  0.174502
#
# Variable Importance: NUM_AS_ROOT:
#     1. "HighGrayLevelEmphasis" 21.000000 ################
#     2.  "LowGrayLevelEmphasis"  7.000000
#
# Variable Importance: NUM_NODES:
#     1. "LargeDependenceHighGrayLevelEmphasis" 109.000000 ################
#     2.                "HighGrayLevelEmphasis" 101.000000 ##############
#     3.                 "LowGrayLevelEmphasis" 76.000000 ##########
#     4.                    "DependenceEntropy" 70.000000 #########
#     5.                    "GrayLevelVariance" 56.000000 #######
#     6.  "SmallDependenceLowGrayLevelEmphasis" 56.000000 #######
#     7.               "GrayLevelNonUniformity" 52.000000 ######
#     8. "SmallDependenceHighGrayLevelEmphasis" 40.000000 ####
#     9.                   "DependenceVariance" 36.000000 ####
#    10.              "SmallDependenceEmphasis" 35.000000 ###
#    11.  "LargeDependenceLowGrayLevelEmphasis" 31.000000 ###
#    12.              "DependenceNonUniformity" 19.000000 #
#    13.              "LargeDependenceEmphasis" 14.000000
#    14.    "DependenceNonUniformityNormalized" 11.000000
#
# Variable Importance: SUM_SCORE:
#     1.                "HighGrayLevelEmphasis" 2370.155229 ################
#     2.                 "LowGrayLevelEmphasis" 155.620395
#     3.  "SmallDependenceLowGrayLevelEmphasis" 155.055618
#     4. "LargeDependenceHighGrayLevelEmphasis" 154.790964
#     5.                    "DependenceEntropy" 110.406699
#     6.              "SmallDependenceEmphasis" 62.437881
#     7.                    "GrayLevelVariance" 56.559453
#     8.               "GrayLevelNonUniformity" 51.865936
#     9. "SmallDependenceHighGrayLevelEmphasis" 50.273104
#    10.  "LargeDependenceLowGrayLevelEmphasis" 43.259319
#    11.                   "DependenceVariance" 32.932825
#    12.              "DependenceNonUniformity" 22.550175
#    13.    "DependenceNonUniformityNormalized" 15.107624
#    14.              "LargeDependenceEmphasis" 10.848560
#
#
#
# Loss: BINOMIAL_LOG_LIKELIHOOD
# Validation loss value: 0.501475
# Number of trees per iteration: 1
# Node format: NOT_SET
# Number of trees: 28
# Total number of nodes: 1440
#
# Number of nodes by tree:
# Count: 28 Average: 51.4286 StdDev: 5.79056
# Min: 39 Max: 63 Ignored: 0
# ----------------------------------------------
# [ 39, 40) 2   7.14%   7.14% ####
# [ 40, 41) 0   0.00%   7.14%
# [ 41, 42) 1   3.57%  10.71% ##
# [ 42, 44) 0   0.00%  10.71%
# [ 44, 45) 0   0.00%  10.71%
# [ 45, 46) 2   7.14%  17.86% ####
# [ 46, 47) 0   0.00%  17.86%
# [ 47, 49) 1   3.57%  21.43% ##
# [ 49, 50) 3  10.71%  32.14% ######
# [ 50, 51) 0   0.00%  32.14%
# [ 51, 52) 5  17.86%  50.00% ##########
# [ 52, 54) 5  17.86%  67.86% ##########
# [ 54, 55) 0   0.00%  67.86%
# [ 55, 56) 4  14.29%  82.14% ########
# [ 56, 57) 0   0.00%  82.14%
# [ 57, 59) 1   3.57%  85.71% ##
# [ 59, 60) 3  10.71%  96.43% ######
# [ 60, 61) 0   0.00%  96.43%
# [ 61, 62) 0   0.00%  96.43%
# [ 62, 63] 1   3.57% 100.00% ##
#
# Depth by leafs:
# Count: 734 Average: 4.8188 StdDev: 0.476849
# Min: 3 Max: 5 Ignored: 0
# ----------------------------------------------
# [ 3, 4)  29   3.95%   3.95%
# [ 4, 5)  75  10.22%  14.17% #
# [ 5, 5] 630  85.83% 100.00% ##########
#
# Number of training obs by leaf:
# Count: 734 Average: 98 StdDev: 280.198
# Min: 5 Max: 2055 Ignored: 0
# ----------------------------------------------
# [    5,  107) 624  85.01%  85.01% ##########
# [  107,  210)  48   6.54%  91.55% #
# [  210,  312)  20   2.72%  94.28%
# [  312,  415)   6   0.82%  95.10%
# [  415,  517)   3   0.41%  95.50%
# [  517,  620)   3   0.41%  95.91%
# [  620,  722)   1   0.14%  96.05%
# [  722,  825)   3   0.41%  96.46%
# [  825,  927)   0   0.00%  96.46%
# [  927, 1030)   0   0.00%  96.46%
# [ 1030, 1133)   3   0.41%  96.87%
# [ 1133, 1235)   2   0.27%  97.14%
# [ 1235, 1338)   3   0.41%  97.55%
# [ 1338, 1440)   5   0.68%  98.23%
# [ 1440, 1543)   2   0.27%  98.50%
# [ 1543, 1645)   7   0.95%  99.46%
# [ 1645, 1748)   1   0.14%  99.59%
# [ 1748, 1850)   1   0.14%  99.73%
# [ 1850, 1953)   1   0.14%  99.86%
# [ 1953, 2055]   1   0.14% 100.00%
#
# Attribute in nodes:
# 	109 : LargeDependenceHighGrayLevelEmphasis [NUMERICAL]
# 	101 : HighGrayLevelEmphasis [NUMERICAL]
# 	76 : LowGrayLevelEmphasis [NUMERICAL]
# 	70 : DependenceEntropy [NUMERICAL]
# 	56 : SmallDependenceLowGrayLevelEmphasis [NUMERICAL]
# 	56 : GrayLevelVariance [NUMERICAL]
# 	52 : GrayLevelNonUniformity [NUMERICAL]
# 	40 : SmallDependenceHighGrayLevelEmphasis [NUMERICAL]
# 	36 : DependenceVariance [NUMERICAL]
# 	35 : SmallDependenceEmphasis [NUMERICAL]
# 	31 : LargeDependenceLowGrayLevelEmphasis [NUMERICAL]
# 	19 : DependenceNonUniformity [NUMERICAL]
# 	14 : LargeDependenceEmphasis [NUMERICAL]
# 	11 : DependenceNonUniformityNormalized [NUMERICAL]
#
# Attribute in nodes with depth <= 0:
# 	21 : HighGrayLevelEmphasis [NUMERICAL]
# 	7 : LowGrayLevelEmphasis [NUMERICAL]
#
# Attribute in nodes with depth <= 1:
# 	35 : HighGrayLevelEmphasis [NUMERICAL]
# 	21 : LowGrayLevelEmphasis [NUMERICAL]
# 	14 : LargeDependenceHighGrayLevelEmphasis [NUMERICAL]
# 	10 : SmallDependenceLowGrayLevelEmphasis [NUMERICAL]
# 	4 : SmallDependenceEmphasis [NUMERICAL]
#
# Attribute in nodes with depth <= 2:
# 	48 : HighGrayLevelEmphasis [NUMERICAL]
# 	35 : LargeDependenceHighGrayLevelEmphasis [NUMERICAL]
# 	34 : LowGrayLevelEmphasis [NUMERICAL]
# 	18 : DependenceEntropy [NUMERICAL]
# 	16 : SmallDependenceLowGrayLevelEmphasis [NUMERICAL]
# 	14 : GrayLevelNonUniformity [NUMERICAL]
# 	10 : GrayLevelVariance [NUMERICAL]
# 	9 : SmallDependenceHighGrayLevelEmphasis [NUMERICAL]
# 	5 : SmallDependenceEmphasis [NUMERICAL]
# 	2 : LargeDependenceLowGrayLevelEmphasis [NUMERICAL]
# 	2 : DependenceVariance [NUMERICAL]
# 	2 : DependenceNonUniformityNormalized [NUMERICAL]
# 	1 : LargeDependenceEmphasis [NUMERICAL]
#
# Attribute in nodes with depth <= 3:
# 	73 : HighGrayLevelEmphasis [NUMERICAL]
# 	64 : LargeDependenceHighGrayLevelEmphasis [NUMERICAL]
# 	49 : LowGrayLevelEmphasis [NUMERICAL]
# 	44 : DependenceEntropy [NUMERICAL]
# 	30 : GrayLevelVariance [NUMERICAL]
# 	28 : GrayLevelNonUniformity [NUMERICAL]
# 	26 : SmallDependenceLowGrayLevelEmphasis [NUMERICAL]
# 	22 : SmallDependenceHighGrayLevelEmphasis [NUMERICAL]
# 	16 : SmallDependenceEmphasis [NUMERICAL]
# 	14 : LargeDependenceLowGrayLevelEmphasis [NUMERICAL]
# 	8 : DependenceVariance [NUMERICAL]
# 	7 : LargeDependenceEmphasis [NUMERICAL]
# 	5 : DependenceNonUniformityNormalized [NUMERICAL]
# 	5 : DependenceNonUniformity [NUMERICAL]
#
# Attribute in nodes with depth <= 5:
# 	109 : LargeDependenceHighGrayLevelEmphasis [NUMERICAL]
# 	101 : HighGrayLevelEmphasis [NUMERICAL]
# 	76 : LowGrayLevelEmphasis [NUMERICAL]
# 	70 : DependenceEntropy [NUMERICAL]
# 	56 : SmallDependenceLowGrayLevelEmphasis [NUMERICAL]
# 	56 : GrayLevelVariance [NUMERICAL]
# 	52 : GrayLevelNonUniformity [NUMERICAL]
# 	40 : SmallDependenceHighGrayLevelEmphasis [NUMERICAL]
# 	36 : DependenceVariance [NUMERICAL]
# 	35 : SmallDependenceEmphasis [NUMERICAL]
# 	31 : LargeDependenceLowGrayLevelEmphasis [NUMERICAL]
# 	19 : DependenceNonUniformity [NUMERICAL]
# 	14 : LargeDependenceEmphasis [NUMERICAL]
# 	11 : DependenceNonUniformityNormalized [NUMERICAL]
#
# Condition type in nodes:
# 	706 : HigherCondition
# Condition type in nodes with depth <= 0:
# 	28 : HigherCondition
# Condition type in nodes with depth <= 1:
# 	84 : HigherCondition
# Condition type in nodes with depth <= 2:
# 	196 : HigherCondition
# Condition type in nodes with depth <= 3:
# 	391 : HigherCondition
# Condition type in nodes with depth <= 5:
# 	706 : HigherCondition
#
# Training logs:
# Number of iteration to final model: 28
# 	Iter:1 train-loss:1.220957 valid-loss:1.245104  train-accuracy:0.956112 valid-accuracy:0.907615
# 	Iter:2 train-loss:1.082563 valid-loss:1.125803  train-accuracy:0.964198 valid-accuracy:0.916563
# 	Iter:3 train-loss:0.966721 valid-loss:1.029970  train-accuracy:0.968317 valid-accuracy:0.914326
# 	Iter:4 train-loss:0.868535 valid-loss:0.958465  train-accuracy:0.970116 valid-accuracy:0.918799
# 	Iter:5 train-loss:0.786043 valid-loss:0.889071  train-accuracy:0.972437 valid-accuracy:0.918799
# 	Iter:6 train-loss:0.713376 valid-loss:0.823336  train-accuracy:0.972886 valid-accuracy:0.918799
# 	Iter:16 train-loss:0.312238 valid-loss:0.555401  train-accuracy:0.981501 valid-accuracy:0.923273
# 	Iter:26 train-loss:0.170587 valid-loss:0.509665  train-accuracy:0.988615 valid-accuracy:0.899449
# 	Iter:36 train-loss:0.112388 valid-loss:0.521829  train-accuracy:0.994156 valid-accuracy:0.873387
# 	Iter:46 train-loss:0.083086 valid-loss:0.551971  train-accuracy:0.995280 valid-accuracy:0.873387
# 	Iter:56 train-loss:0.064213 valid-loss:0.580782  train-accuracy:0.996628 valid-accuracy:0.873387

# %%
# Model features
model.make_inspector().features()
# Out:
# ["DependenceEntropy" (1; #0),
#  "DependenceNonUniformity" (1; #1),
#  "DependenceNonUniformityNormalized" (1; #2),
#  "DependenceVariance" (1; #3),
#  "GrayLevelNonUniformity" (1; #4),
#  "GrayLevelVariance" (1; #5),
#  "HighGrayLevelEmphasis" (1; #6),
#  "LargeDependenceEmphasis" (1; #7),
#  "LargeDependenceHighGrayLevelEmphasis" (1; #8),
#  "LargeDependenceLowGrayLevelEmphasis" (1; #9),
#  "LowGrayLevelEmphasis" (1; #10),
#  "SmallDependenceEmphasis" (1; #11),
#  "SmallDependenceHighGrayLevelEmphasis" (1; #12),
#  "SmallDependenceLowGrayLevelEmphasis" (1; #13)]

# %%
# Feature importance
model.make_inspector().variable_importances()
# Out:
# {'INV_MEAN_MIN_DEPTH': [("HighGrayLevelEmphasis" (1; #6), 0.5866383972380004),
#   ("LowGrayLevelEmphasis" (1; #10), 0.28459954008617633),
#   ("LargeDependenceHighGrayLevelEmphasis" (1; #8), 0.24110636857943146),
#   ("SmallDependenceLowGrayLevelEmphasis" (1; #13), 0.2088453832996597),
#   ("DependenceEntropy" (1; #0), 0.19793916637909606),
#   ("GrayLevelVariance" (1; #5), 0.1885667821379388),
#   ("GrayLevelNonUniformity" (1; #4), 0.1873497921424166),
#   ("SmallDependenceHighGrayLevelEmphasis" (1; #12), 0.18660831304981693),
#   ("SmallDependenceEmphasis" (1; #11), 0.18535470154196604),
#   ("LargeDependenceLowGrayLevelEmphasis" (1; #9), 0.17765963285890637),
#   ("DependenceVariance" (1; #3), 0.17695124045758714),
#   ("DependenceNonUniformityNormalized" (1; #2), 0.1748953510303978),
#   ("LargeDependenceEmphasis" (1; #7), 0.17454560475510356),
#   ("DependenceNonUniformity" (1; #1), 0.17450206652729036)],
#  'NUM_AS_ROOT': [("HighGrayLevelEmphasis" (1; #6), 21.0),
#   ("LowGrayLevelEmphasis" (1; #10), 7.0)],
#  'SUM_SCORE': [("HighGrayLevelEmphasis" (1; #6), 2370.155229312009),
#   ("LowGrayLevelEmphasis" (1; #10), 155.62039467239245),
#   ("SmallDependenceLowGrayLevelEmphasis" (1; #13), 155.0556176006227),
#   ("LargeDependenceHighGrayLevelEmphasis" (1; #8), 154.79096353796788),
#   ("DependenceEntropy" (1; #0), 110.40669923535258),
#   ("SmallDependenceEmphasis" (1; #11), 62.43788085427064),
#   ("GrayLevelVariance" (1; #5), 56.55945321266344),
#   ("GrayLevelNonUniformity" (1; #4), 51.865936214539616),
#   ("SmallDependenceHighGrayLevelEmphasis" (1; #12), 50.27310370391093),
#   ("LargeDependenceLowGrayLevelEmphasis" (1; #9), 43.25931851230586),
#   ("DependenceVariance" (1; #3), 32.93282530457217),
#   ("DependenceNonUniformity" (1; #1), 22.550174538069843),
#   ("DependenceNonUniformityNormalized" (1; #2), 15.107623552181838),
#   ("LargeDependenceEmphasis" (1; #7), 10.848559866383392)],
#  'NUM_NODES': [("LargeDependenceHighGrayLevelEmphasis" (1; #8), 109.0),
#   ("HighGrayLevelEmphasis" (1; #6), 101.0),
#   ("LowGrayLevelEmphasis" (1; #10), 76.0),
#   ("DependenceEntropy" (1; #0), 70.0),
#   ("GrayLevelVariance" (1; #5), 56.0),
#   ("SmallDependenceLowGrayLevelEmphasis" (1; #13), 56.0),
#   ("GrayLevelNonUniformity" (1; #4), 52.0),
#   ("SmallDependenceHighGrayLevelEmphasis" (1; #12), 40.0),
#   ("DependenceVariance" (1; #3), 36.0),
#   ("SmallDependenceEmphasis" (1; #11), 35.0),
#   ("LargeDependenceLowGrayLevelEmphasis" (1; #9), 31.0),
#   ("DependenceNonUniformity" (1; #1), 19.0),
#   ("LargeDependenceEmphasis" (1; #7), 14.0),
#   ("DependenceNonUniformityNormalized" (1; #2), 11.0)]}

# %%
# Model self evaluation
model.make_inspector().evaluation()
# Out:
# Evaluation(num_examples=None, accuracy=0.8711506724357605, loss=0.501474916934967, rmse=None, ndcg=None, aucs=None, auuc=None, qini=None)

# %%
logs = model.make_inspector().training_logs()

plt.figure(figsize=(12, 4))
plt.subplot(1, 2, 1)
plt.plot([log.num_trees for log in logs], [log.evaluation.accuracy for log in logs])
plt.xlabel("Number of trees")
plt.ylabel("Accuracy (out-of-bag)")
plt.subplot(1, 2, 2)
plt.plot([log.num_trees for log in logs], [log.evaluation.loss for log in logs])
plt.xlabel("Number of trees")
plt.ylabel("Logloss (out-of-bag)")
plt.show()

# %% [markdown]
# Calculate the score of our hold-out validation dataset

# %%
predictions = model.predict(val_ds)
y_true      = validation_data["label"]

from sklearn.metrics import roc_auc_score
ROC_AUC = roc_auc_score(y_true, predictions)
print("The ROC AUC score is %.5f" % ROC_AUC )
# Out:
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 67ms/step
# The ROC AUC score is 0.99317

# %%
# Compute binary classification metrics with sklearn
import numpy as np
from sklearn.metrics import (
    accuracy_score,
    precision_score,
    recall_score,
    f1_score,
    roc_auc_score,
    average_precision_score,
    confusion_matrix,
    classification_report,
    matthews_corrcoef,
    log_loss,
    brier_score_loss,
)

# Get predictions (probabilities or class labels)
preds = model.predict(test_ds)
# If model outputs probabilities, convert to labels by threshold 0.5
if preds.ndim == 2:
    # For TFDF classification, preds may be class probabilities with shape (N, 2)
    if preds.shape[1] == 2:
        pos_probs = preds[:, 1]
    else:
        # If single-probability column (positive class)
        pos_probs = preds[:, -1]
    y_pred = (pos_probs >= 0.5).astype(int)
else:
    # Already class labels
    y_pred = preds.astype(int)
    pos_probs = None

# Ground truth labels (must be 0/1 integers)
y_true = test_data["label"].astype(int).to_numpy()

# Core metrics
metrics = {}
metrics["accuracy"] = accuracy_score(y_true, y_pred)
metrics["precision"] = precision_score(y_true, y_pred, zero_division=0)
metrics["recall"] = recall_score(y_true, y_pred, zero_division=0)
metrics["f1"] = f1_score(y_true, y_pred, zero_division=0)
metrics["mcc"] = matthews_corrcoef(y_true, y_pred)

# Probabilistic metrics (only if we have probabilities)
if pos_probs is not None:
    metrics["roc_auc"] = roc_auc_score(y_true, pos_probs)
    metrics["pr_auc"] = average_precision_score(y_true, pos_probs)
    metrics["log_loss"] = log_loss(y_true, pos_probs, labels=[0,1])
    metrics["brier_score"] = brier_score_loss(y_true, pos_probs)

# Confusion matrix and detailed report
cm = confusion_matrix(y_true, y_pred, labels=[0,1])
report = classification_report(y_true, y_pred, digits=4)

print("Sklearn binary metrics:")
for k, v in metrics.items():
    print(f"{k}: {v:.4f}")
print("\nConfusion matrix:\n", cm)
print("\nClassification report:\n", report)
# Out:
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 71ms/step
# Sklearn binary metrics:
# accuracy: 0.9531
# precision: 0.8148
# recall: 0.8302
# f1: 0.8224
# mcc: 0.7955
# roc_auc: 0.9801
# pr_auc: 0.9134
# log_loss: 0.1469
# brier_score: 0.0377
#
# Confusion matrix:
#  [[685  20]
#  [ 18  88]]
#
# Classification report:
#                precision    recall  f1-score   support
#
#            0     0.9744    0.9716    0.9730       705
#            1     0.8148    0.8302    0.8224       106
#
#     accuracy                         0.9531       811
#    macro avg     0.8946    0.9009    0.8977       811
# weighted avg     0.9535    0.9531    0.9533       811
