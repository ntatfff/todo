# %%
# Import packages and modules
import numpy  as np
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow_decision_forests as tfdf

from sklearn.model_selection import train_test_split
# Out:
# 2026-08-13 04:23:56.256246: I tensorflow/core/util/port.cc:113] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2026-08-13 04:23:56.642214: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2026-08-13 04:24:01.616676: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
# Check the version of TensorFlow Decision Forests
print("Found TensorFlow Decision Forests v" + tfdf.__version__)
# Out:
# Found TensorFlow Decision Forests v1.9.1

# %%
datasetPath = 'dataset/firstorder/kernel5/dataset.csv'

# %%
# Parameters
datasetPath = "dataset/glrlm/kernel3/1.dataset.csv"

# %%
# train/validation/test = 70/10/20
dataset = pd.read_csv(datasetPath)

train_data, temp_data = train_test_split(dataset, test_size=0.3, random_state=42)
validation_data, test_data = train_test_split(temp_data, test_size=2/3, random_state=42)

# %%
from sklearn.utils.class_weight import compute_class_weight

# tinh class weight tren tap train
classes = np.array([0, 1])
weights = compute_class_weight(class_weight="balanced", classes=classes, y=train_data["label"])
class_weight = {0: weights[0], 1: weights[1]}

# gan sample_weight cho tung dong
train_data["sample_weight"] = train_data["label"].map(class_weight)
validation_data["sample_weight"] = validation_data["label"].map(class_weight)
test_data["sample_weight"] = test_data["label"].map(class_weight)

# Convert the dataset into a TensorFlow dataset.
train_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    train_data, label="label", weight="sample_weight"
)         
val_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    validation_data, label="label", weight="sample_weight"
)
test_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    test_data, label="label", weight="sample_weight"
)
# Out:
# 2026-08-13 04:24:15.631440: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:984] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2026-08-13 04:24:15.632885: W tensorflow/core/common_runtime/gpu/gpu_device.cc:2251] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...

# %%
import keras

# %%
# %%time

# Train a Random Forest model.
model = tfdf.keras.RandomForestModel()

# Add evaluation metrics
model.compile(
    metrics=["accuracy"]
)
model.fit(x=train_ds)

# # Train a Gradient Boosted Trees model.
# model = tfdf.keras.GradientBoostedTreesModel(num_trees=1500)
# model.fit(train_ds)
# Out:
# Use /tmp/tmpnhoitret as temporary training directory
# Reading training dataset...
# Training dataset read in 0:00:02.684457. Found 2835 examples.
# Training model...
# Model trained in 0:00:00.195872
# Compiling model...
# [INFO 26-08-13 04:24:18.6467 UTC kernel.cc:1233] Loading model from path /tmp/tmpnhoitret/model/ with prefix c89b93caf1ea4571
# [INFO 26-08-13 04:24:18.6914 UTC decision_forest.cc:734] Model loaded with 300 root(s), 32542 node(s), and 16 input feature(s).
# [INFO 26-08-13 04:24:18.6914 UTC abstract_model.cc:1362] Engine "RandomForestOptPred" built
# [INFO 26-08-13 04:24:18.6914 UTC kernel.cc:1061] Use fast generic engine
# Model compiled.
# CPU times: user 6.58 s, sys: 135 ms, total: 6.72 s
# Wall time: 6.2 s

# %%
# Evaluate the model
evaluate = model.evaluate(val_ds, return_dict=True)
print()

for name, value in evaluate.items():
    print(f"{name}: {value:.4f}")
# Out:
# WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 1/1 [==============================] - ETA: 0s - loss: 0.0000e+00 - accuracy: 0.9605
# 1/1 [==============================] - 3s 3s/step - loss: 0.0000e+00 - accuracy: 0.9605
# loss: 0.0000
# accuracy: 0.9605

# %%
# Model Summary
model.summary()
# Out:
# Model: "random_forest_model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
# =================================================================
# Total params: 1 (1.00 Byte)
# Trainable params: 0 (0.00 Byte)
# Non-trainable params: 1 (1.00 Byte)
# _________________________________________________________________
# Type: "RANDOM_FOREST"
# Task: CLASSIFICATION
# Label: "__LABEL"
#
# Input Features (16):
# 	GrayLevelNonUniformity
# 	GrayLevelNonUniformityNormalized
# 	GrayLevelVariance
# 	HighGrayLevelRunEmphasis
# 	LongRunEmphasis
# 	LongRunHighGrayLevelEmphasis
# 	LongRunLowGrayLevelEmphasis
# 	LowGrayLevelRunEmphasis
# 	RunEntropy
# 	RunLengthNonUniformity
# 	RunLengthNonUniformityNormalized
# 	RunPercentage
# 	RunVariance
# 	ShortRunEmphasis
# 	ShortRunHighGrayLevelEmphasis
# 	ShortRunLowGrayLevelEmphasis
#
# Trained with weights
#
# Variable Importance: INV_MEAN_MIN_DEPTH:
#     1.     "LongRunHighGrayLevelEmphasis"  0.288537 ################
#     2.         "HighGrayLevelRunEmphasis"  0.202397 #######
#     3.     "ShortRunLowGrayLevelEmphasis"  0.170874 ####
#     4.    "ShortRunHighGrayLevelEmphasis"  0.169041 ###
#     5.          "LowGrayLevelRunEmphasis"  0.166430 ###
#     6.                       "RunEntropy"  0.141044
#     7.                      "RunVariance"  0.140910
#     8.                  "LongRunEmphasis"  0.139707
#     9.           "GrayLevelNonUniformity"  0.138971
#    10.      "LongRunLowGrayLevelEmphasis"  0.138489
#    11.                "GrayLevelVariance"  0.137436
#    12. "GrayLevelNonUniformityNormalized"  0.137064
#    13.                 "ShortRunEmphasis"  0.134663
#    14.           "RunLengthNonUniformity"  0.134644
#    15. "RunLengthNonUniformityNormalized"  0.133569
#    16.                    "RunPercentage"  0.131389
#
# Variable Importance: NUM_AS_ROOT:
#     1.     "LongRunHighGrayLevelEmphasis" 93.000000 ################
#     2.         "HighGrayLevelRunEmphasis" 70.000000 ############
#     3.          "LowGrayLevelRunEmphasis" 52.000000 ########
#     4.     "ShortRunLowGrayLevelEmphasis" 34.000000 #####
#     5.    "ShortRunHighGrayLevelEmphasis" 26.000000 ####
#     6.      "LongRunLowGrayLevelEmphasis" 11.000000 #
#     7.                  "LongRunEmphasis"  5.000000
#     8.                      "RunVariance"  3.000000
#     9.           "GrayLevelNonUniformity"  2.000000
#    10. "GrayLevelNonUniformityNormalized"  1.000000
#    11.                       "RunEntropy"  1.000000
#    12.           "RunLengthNonUniformity"  1.000000
#    13.                    "RunPercentage"  1.000000
#
# Variable Importance: NUM_NODES:
#     1.     "LongRunHighGrayLevelEmphasis" 1745.000000 ################
#     2.         "HighGrayLevelRunEmphasis" 1235.000000 ########
#     3.     "ShortRunLowGrayLevelEmphasis" 1168.000000 #######
#     4.                "GrayLevelVariance" 1149.000000 #######
#     5.                       "RunEntropy" 1148.000000 #######
#     6.    "ShortRunHighGrayLevelEmphasis" 1110.000000 ######
#     7.          "LowGrayLevelRunEmphasis" 1074.000000 ######
#     8.           "GrayLevelNonUniformity" 1044.000000 #####
#     9. "GrayLevelNonUniformityNormalized" 943.000000 ####
#    10.      "LongRunLowGrayLevelEmphasis" 933.000000 ####
#    11.                      "RunVariance" 887.000000 ###
#    12.                  "LongRunEmphasis" 821.000000 ##
#    13.           "RunLengthNonUniformity" 752.000000 #
#    14.                 "ShortRunEmphasis" 749.000000 #
#    15. "RunLengthNonUniformityNormalized" 710.000000
#    16.                    "RunPercentage" 653.000000
#
# Variable Importance: SUM_SCORE:
#     1.     "LongRunHighGrayLevelEmphasis" 173370.235897 ################
#     2.         "HighGrayLevelRunEmphasis" 102074.049990 #########
#     3.          "LowGrayLevelRunEmphasis" 68356.517210 #####
#     4.     "ShortRunLowGrayLevelEmphasis" 54605.135812 ####
#     5.    "ShortRunHighGrayLevelEmphasis" 46992.854916 ###
#     6.      "LongRunLowGrayLevelEmphasis" 17640.761247 #
#     7.                       "RunEntropy" 13450.761206
#     8.           "GrayLevelNonUniformity" 12126.520152
#     9.                "GrayLevelVariance" 11275.420529
#    10. "GrayLevelNonUniformityNormalized" 11043.287948
#    11.                      "RunVariance" 9702.369824
#    12.                  "LongRunEmphasis" 9470.434155
#    13.                 "ShortRunEmphasis" 8193.419881
#    14.           "RunLengthNonUniformity" 8030.704731
#    15. "RunLengthNonUniformityNormalized" 7179.651840
#    16.                    "RunPercentage" 6725.648863
#
#
#
# Winner takes all: true
# Out-of-bag evaluation: accuracy:0.911569 logloss:0.292818
# Number of trees: 300
# Total number of nodes: 32542
#
# Number of nodes by tree:
# Count: 300 Average: 108.473 StdDev: 8.65193
# Min: 81 Max: 131 Ignored: 0
# ----------------------------------------------
# [  81,  83)  1   0.33%   0.33%
# [  83,  86)  1   0.33%   0.67%
# [  86,  88)  0   0.00%   0.67%
# [  88,  91)  5   1.67%   2.33% #
# [  91,  93)  2   0.67%   3.00%
# [  93,  96)  8   2.67%   5.67% #
# [  96,  98) 14   4.67%  10.33% ###
# [  98, 101) 13   4.33%  14.67% ##
# [ 101, 103) 20   6.67%  21.33% ####
# [ 103, 106) 55  18.33%  39.67% ##########
# [ 106, 109) 34  11.33%  51.00% ######
# [ 109, 111) 19   6.33%  57.33% ###
# [ 111, 114) 52  17.33%  74.67% #########
# [ 114, 116) 20   6.67%  81.33% ####
# [ 116, 119) 15   5.00%  86.33% ###
# [ 119, 121)  8   2.67%  89.00% #
# [ 121, 124) 23   7.67%  96.67% ####
# [ 124, 126)  4   1.33%  98.00% #
# [ 126, 129)  3   1.00%  99.00% #
# [ 129, 131]  3   1.00% 100.00% #
#
# Depth by leafs:
# Count: 16421 Average: 7.40741 StdDev: 2.33458
# Min: 2 Max: 15 Ignored: 0
# ----------------------------------------------
# [  2,  3)  150   0.91%   0.91% #
# [  3,  4)  579   3.53%   4.44% ##
# [  4,  5)  956   5.82%  10.26% ###
# [  5,  6) 1664  10.13%  20.39% ######
# [  6,  7) 2571  15.66%  36.05% #########
# [  7,  8) 2786  16.97%  53.02% ##########
# [  8,  9) 2679  16.31%  69.33% ##########
# [  9, 10) 2111  12.86%  82.19% ########
# [ 10, 11) 1343   8.18%  90.37% #####
# [ 11, 12)  825   5.02%  95.39% ###
# [ 12, 13)  429   2.61%  98.00% ##
# [ 13, 14)  196   1.19%  99.20% #
# [ 14, 15)   84   0.51%  99.71%
# [ 15, 15]   48   0.29% 100.00%
#
# Number of training obs by leaf:
# Count: 16421 Average: 51.7934 StdDev: 150.938
# Min: 5 Max: 1773 Ignored: 0
# ----------------------------------------------
# [    5,   93) 14675  89.37%  89.37% ##########
# [   93,  181)   549   3.34%  92.71%
# [  181,  270)   479   2.92%  95.63%
# [  270,  358)   121   0.74%  96.36%
# [  358,  447)   104   0.63%  97.00%
# [  447,  535)    84   0.51%  97.51%
# [  535,  624)    76   0.46%  97.97%
# [  624,  712)    55   0.33%  98.31%
# [  712,  801)    65   0.40%  98.70%
# [  801,  889)    54   0.33%  99.03%
# [  889,  977)    47   0.29%  99.32%
# [  977, 1066)    26   0.16%  99.48%
# [ 1066, 1154)    30   0.18%  99.66%
# [ 1154, 1243)    20   0.12%  99.78%
# [ 1243, 1331)    10   0.06%  99.84%
# [ 1331, 1420)     8   0.05%  99.89%
# [ 1420, 1508)    10   0.06%  99.95%
# [ 1508, 1597)     4   0.02%  99.98%
# [ 1597, 1685)     2   0.01%  99.99%
# [ 1685, 1773]     2   0.01% 100.00%
#
# Attribute in nodes:
# 	1745 : LongRunHighGrayLevelEmphasis [NUMERICAL]
# 	1235 : HighGrayLevelRunEmphasis [NUMERICAL]
# 	1168 : ShortRunLowGrayLevelEmphasis [NUMERICAL]
# 	1149 : GrayLevelVariance [NUMERICAL]
# 	1148 : RunEntropy [NUMERICAL]
# 	1110 : ShortRunHighGrayLevelEmphasis [NUMERICAL]
# 	1074 : LowGrayLevelRunEmphasis [NUMERICAL]
# 	1044 : GrayLevelNonUniformity [NUMERICAL]
# 	943 : GrayLevelNonUniformityNormalized [NUMERICAL]
# 	933 : LongRunLowGrayLevelEmphasis [NUMERICAL]
# 	887 : RunVariance [NUMERICAL]
# 	821 : LongRunEmphasis [NUMERICAL]
# 	752 : RunLengthNonUniformity [NUMERICAL]
# 	749 : ShortRunEmphasis [NUMERICAL]
# 	710 : RunLengthNonUniformityNormalized [NUMERICAL]
# 	653 : RunPercentage [NUMERICAL]
#
# Attribute in nodes with depth <= 0:
# 	93 : LongRunHighGrayLevelEmphasis [NUMERICAL]
# 	70 : HighGrayLevelRunEmphasis [NUMERICAL]
# 	52 : LowGrayLevelRunEmphasis [NUMERICAL]
# 	34 : ShortRunLowGrayLevelEmphasis [NUMERICAL]
# 	26 : ShortRunHighGrayLevelEmphasis [NUMERICAL]
# 	11 : LongRunLowGrayLevelEmphasis [NUMERICAL]
# 	5 : LongRunEmphasis [NUMERICAL]
# 	3 : RunVariance [NUMERICAL]
# 	2 : GrayLevelNonUniformity [NUMERICAL]
# 	1 : RunPercentage [NUMERICAL]
# 	1 : RunLengthNonUniformity [NUMERICAL]
# 	1 : RunEntropy [NUMERICAL]
# 	1 : GrayLevelNonUniformityNormalized [NUMERICAL]
#
# Attribute in nodes with depth <= 1:
# 	273 : LongRunHighGrayLevelEmphasis [NUMERICAL]
# 	170 : HighGrayLevelRunEmphasis [NUMERICAL]
# 	125 : ShortRunLowGrayLevelEmphasis [NUMERICAL]
# 	107 : ShortRunHighGrayLevelEmphasis [NUMERICAL]
# 	103 : LowGrayLevelRunEmphasis [NUMERICAL]
# 	28 : LongRunLowGrayLevelEmphasis [NUMERICAL]
# 	19 : GrayLevelNonUniformityNormalized [NUMERICAL]
# 	19 : GrayLevelNonUniformity [NUMERICAL]
# 	16 : RunVariance [NUMERICAL]
# 	11 : LongRunEmphasis [NUMERICAL]
# 	7 : RunPercentage [NUMERICAL]
# 	7 : RunEntropy [NUMERICAL]
# 	6 : RunLengthNonUniformity [NUMERICAL]
# 	6 : GrayLevelVariance [NUMERICAL]
# 	2 : ShortRunEmphasis [NUMERICAL]
# 	1 : RunLengthNonUniformityNormalized [NUMERICAL]
#
# Attribute in nodes with depth <= 2:
# 	439 : LongRunHighGrayLevelEmphasis [NUMERICAL]
# 	292 : HighGrayLevelRunEmphasis [NUMERICAL]
# 	198 : ShortRunHighGrayLevelEmphasis [NUMERICAL]
# 	196 : ShortRunLowGrayLevelEmphasis [NUMERICAL]
# 	148 : LowGrayLevelRunEmphasis [NUMERICAL]
# 	94 : GrayLevelNonUniformity [NUMERICAL]
# 	78 : GrayLevelNonUniformityNormalized [NUMERICAL]
# 	76 : RunVariance [NUMERICAL]
# 	74 : LongRunEmphasis [NUMERICAL]
# 	64 : RunLengthNonUniformity [NUMERICAL]
# 	63 : LongRunLowGrayLevelEmphasis [NUMERICAL]
# 	55 : RunEntropy [NUMERICAL]
# 	51 : ShortRunEmphasis [NUMERICAL]
# 	49 : RunLengthNonUniformityNormalized [NUMERICAL]
# 	42 : RunPercentage [NUMERICAL]
# 	31 : GrayLevelVariance [NUMERICAL]
#
# Attribute in nodes with depth <= 3:
# 	661 : LongRunHighGrayLevelEmphasis [NUMERICAL]
# 	409 : HighGrayLevelRunEmphasis [NUMERICAL]
# 	307 : ShortRunHighGrayLevelEmphasis [NUMERICAL]
# 	283 : ShortRunLowGrayLevelEmphasis [NUMERICAL]
# 	225 : LowGrayLevelRunEmphasis [NUMERICAL]
# 	184 : RunEntropy [NUMERICAL]
# 	171 : GrayLevelNonUniformity [NUMERICAL]
# 	159 : GrayLevelNonUniformityNormalized [NUMERICAL]
# 	155 : RunVariance [NUMERICAL]
# 	143 : LongRunEmphasis [NUMERICAL]
# 	142 : RunLengthNonUniformity [NUMERICAL]
# 	139 : LongRunLowGrayLevelEmphasis [NUMERICAL]
# 	138 : ShortRunEmphasis [NUMERICAL]
# 	128 : RunLengthNonUniformityNormalized [NUMERICAL]
# 	128 : GrayLevelVariance [NUMERICAL]
# 	99 : RunPercentage [NUMERICAL]
#
# Attribute in nodes with depth <= 5:
# 	1105 : LongRunHighGrayLevelEmphasis [NUMERICAL]
# 	730 : HighGrayLevelRunEmphasis [NUMERICAL]
# 	609 : ShortRunHighGrayLevelEmphasis [NUMERICAL]
# 	595 : ShortRunLowGrayLevelEmphasis [NUMERICAL]
# 	559 : RunEntropy [NUMERICAL]
# 	511 : LowGrayLevelRunEmphasis [NUMERICAL]
# 	503 : GrayLevelVariance [NUMERICAL]
# 	479 : GrayLevelNonUniformity [NUMERICAL]
# 	431 : GrayLevelNonUniformityNormalized [NUMERICAL]
# 	420 : LongRunLowGrayLevelEmphasis [NUMERICAL]
# 	401 : RunVariance [NUMERICAL]
# 	369 : LongRunEmphasis [NUMERICAL]
# 	366 : ShortRunEmphasis [NUMERICAL]
# 	362 : RunLengthNonUniformity [NUMERICAL]
# 	338 : RunLengthNonUniformityNormalized [NUMERICAL]
# 	287 : RunPercentage [NUMERICAL]
#
# Condition type in nodes:
# 	16121 : HigherCondition
# Condition type in nodes with depth <= 0:
# 	300 : HigherCondition
# Condition type in nodes with depth <= 1:
# 	900 : HigherCondition
# Condition type in nodes with depth <= 2:
# 	1950 : HigherCondition
# Condition type in nodes with depth <= 3:
# 	3471 : HigherCondition
# Condition type in nodes with depth <= 5:
# 	8065 : HigherCondition
# Node format: NOT_SET
#
# Training OOB:
# 	trees: 1, Out-of-bag evaluation: accuracy:0.880105 logloss:4.32145
# 	trees: 13, Out-of-bag evaluation: accuracy:0.901341 logloss:1.84661
# 	trees: 23, Out-of-bag evaluation: accuracy:0.908621 logloss:0.785954
# 	trees: 33, Out-of-bag evaluation: accuracy:0.915022 logloss:0.606111
# 	trees: 43, Out-of-bag evaluation: accuracy:0.916439 logloss:0.603133
# 	trees: 53, Out-of-bag evaluation: accuracy:0.917758 logloss:0.598454
# 	trees: 63, Out-of-bag evaluation: accuracy:0.915022 logloss:0.55766
# 	trees: 73, Out-of-bag evaluation: accuracy:0.915731 logloss:0.514293
# 	trees: 83, Out-of-bag evaluation: accuracy:0.914004 logloss:0.424078
# 	trees: 93, Out-of-bag evaluation: accuracy:0.914208 logloss:0.423075
# 	trees: 103, Out-of-bag evaluation: accuracy:0.912888 logloss:0.425675
# 	trees: 113, Out-of-bag evaluation: accuracy:0.914004 logloss:0.426069
# 	trees: 123, Out-of-bag evaluation: accuracy:0.914509 logloss:0.378443
# 	trees: 133, Out-of-bag evaluation: accuracy:0.913393 logloss:0.335713
# 	trees: 143, Out-of-bag evaluation: accuracy:0.910551 logloss:0.33527
# 	trees: 153, Out-of-bag evaluation: accuracy:0.912074 logloss:0.335353
# 	trees: 163, Out-of-bag evaluation: accuracy:0.912685 logloss:0.334339
# 	trees: 173, Out-of-bag evaluation: accuracy:0.913597 logloss:0.334819
# 	trees: 183, Out-of-bag evaluation: accuracy:0.914004 logloss:0.333987
# 	trees: 193, Out-of-bag evaluation: accuracy:0.913801 logloss:0.292245
# 	trees: 203, Out-of-bag evaluation: accuracy:0.912278 logloss:0.292863
# 	trees: 213, Out-of-bag evaluation: accuracy:0.910755 logloss:0.293882
# 	trees: 223, Out-of-bag evaluation: accuracy:0.912888 logloss:0.294101
# 	trees: 233, Out-of-bag evaluation: accuracy:0.908931 logloss:0.29362
# 	trees: 243, Out-of-bag evaluation: accuracy:0.911569 logloss:0.292234
# 	trees: 253, Out-of-bag evaluation: accuracy:0.912481 logloss:0.291936
# 	trees: 264, Out-of-bag evaluation: accuracy:0.911871 logloss:0.292309
# 	trees: 274, Out-of-bag evaluation: accuracy:0.913393 logloss:0.292186
# 	trees: 284, Out-of-bag evaluation: accuracy:0.911366 logloss:0.292992
# 	trees: 294, Out-of-bag evaluation: accuracy:0.911366 logloss:0.292929
# 	trees: 300, Out-of-bag evaluation: accuracy:0.911569 logloss:0.292818

# %%
# Model features
model.make_inspector().features()
# Out:
# ["GrayLevelNonUniformity" (1; #0),
#  "GrayLevelNonUniformityNormalized" (1; #1),
#  "GrayLevelVariance" (1; #2),
#  "HighGrayLevelRunEmphasis" (1; #3),
#  "LongRunEmphasis" (1; #4),
#  "LongRunHighGrayLevelEmphasis" (1; #5),
#  "LongRunLowGrayLevelEmphasis" (1; #6),
#  "LowGrayLevelRunEmphasis" (1; #7),
#  "RunEntropy" (1; #8),
#  "RunLengthNonUniformity" (1; #9),
#  "RunLengthNonUniformityNormalized" (1; #10),
#  "RunPercentage" (1; #11),
#  "RunVariance" (1; #12),
#  "ShortRunEmphasis" (1; #13),
#  "ShortRunHighGrayLevelEmphasis" (1; #14),
#  "ShortRunLowGrayLevelEmphasis" (1; #15)]

# %%
# Feature importance
model.make_inspector().variable_importances()
# Out:
# {'INV_MEAN_MIN_DEPTH': [("LongRunHighGrayLevelEmphasis" (1; #5),
#    0.288536771542222),
#   ("HighGrayLevelRunEmphasis" (1; #3), 0.20239735988660934),
#   ("ShortRunLowGrayLevelEmphasis" (1; #15), 0.1708743154401218),
#   ("ShortRunHighGrayLevelEmphasis" (1; #14), 0.16904083120399907),
#   ("LowGrayLevelRunEmphasis" (1; #7), 0.1664300025007738),
#   ("RunEntropy" (1; #8), 0.14104364682085693),
#   ("RunVariance" (1; #12), 0.14091017236527456),
#   ("LongRunEmphasis" (1; #4), 0.13970694805770456),
#   ("GrayLevelNonUniformity" (1; #0), 0.13897078722626333),
#   ("LongRunLowGrayLevelEmphasis" (1; #6), 0.13848872641078236),
#   ("GrayLevelVariance" (1; #2), 0.13743586750043818),
#   ("GrayLevelNonUniformityNormalized" (1; #1), 0.1370636525498572),
#   ("ShortRunEmphasis" (1; #13), 0.1346626064384059),
#   ("RunLengthNonUniformity" (1; #9), 0.13464419024181482),
#   ("RunLengthNonUniformityNormalized" (1; #10), 0.133569249294497),
#   ("RunPercentage" (1; #11), 0.1313885897853979)],
#  'SUM_SCORE': [("LongRunHighGrayLevelEmphasis" (1; #5), 173370.2358966473),
#   ("HighGrayLevelRunEmphasis" (1; #3), 102074.04998981282),
#   ("LowGrayLevelRunEmphasis" (1; #7), 68356.51721009242),
#   ("ShortRunLowGrayLevelEmphasis" (1; #15), 54605.13581208274),
#   ("ShortRunHighGrayLevelEmphasis" (1; #14), 46992.854916070115),
#   ("LongRunLowGrayLevelEmphasis" (1; #6), 17640.761246905837),
#   ("RunEntropy" (1; #8), 13450.761206209907),
#   ("GrayLevelNonUniformity" (1; #0), 12126.520152451709),
#   ("GrayLevelVariance" (1; #2), 11275.42052881188),
#   ("GrayLevelNonUniformityNormalized" (1; #1), 11043.28794753113),
#   ("RunVariance" (1; #12), 9702.369824302237),
#   ("LongRunEmphasis" (1; #4), 9470.43415491323),
#   ("ShortRunEmphasis" (1; #13), 8193.41988061357),
#   ("RunLengthNonUniformity" (1; #9), 8030.70473133756),
#   ("RunLengthNonUniformityNormalized" (1; #10), 7179.651839641994),
#   ("RunPercentage" (1; #11), 6725.64886254481)],
#  'NUM_AS_ROOT': [("LongRunHighGrayLevelEmphasis" (1; #5), 93.0),
#   ("HighGrayLevelRunEmphasis" (1; #3), 70.0),
#   ("LowGrayLevelRunEmphasis" (1; #7), 52.0),
#   ("ShortRunLowGrayLevelEmphasis" (1; #15), 34.0),
#   ("ShortRunHighGrayLevelEmphasis" (1; #14), 26.0),
#   ("LongRunLowGrayLevelEmphasis" (1; #6), 11.0),
#   ("LongRunEmphasis" (1; #4), 5.0),
#   ("RunVariance" (1; #12), 3.0),
#   ("GrayLevelNonUniformity" (1; #0), 2.0),
#   ("GrayLevelNonUniformityNormalized" (1; #1), 1.0),
#   ("RunEntropy" (1; #8), 1.0),
#   ("RunLengthNonUniformity" (1; #9), 1.0),
#   ("RunPercentage" (1; #11), 1.0)],
#  'NUM_NODES': [("LongRunHighGrayLevelEmphasis" (1; #5), 1745.0),
#   ("HighGrayLevelRunEmphasis" (1; #3), 1235.0),
#   ("ShortRunLowGrayLevelEmphasis" (1; #15), 1168.0),
#   ("GrayLevelVariance" (1; #2), 1149.0),
#   ("RunEntropy" (1; #8), 1148.0),
#   ("ShortRunHighGrayLevelEmphasis" (1; #14), 1110.0),
#   ("LowGrayLevelRunEmphasis" (1; #7), 1074.0),
#   ("GrayLevelNonUniformity" (1; #0), 1044.0),
#   ("GrayLevelNonUniformityNormalized" (1; #1), 943.0),
#   ("LongRunLowGrayLevelEmphasis" (1; #6), 933.0),
#   ("RunVariance" (1; #12), 887.0),
#   ("LongRunEmphasis" (1; #4), 821.0),
#   ("RunLengthNonUniformity" (1; #9), 752.0),
#   ("ShortRunEmphasis" (1; #13), 749.0),
#   ("RunLengthNonUniformityNormalized" (1; #10), 710.0),
#   ("RunPercentage" (1; #11), 653.0)]}

# %%
# Model self evaluation
model.make_inspector().evaluation()
# Out:
# Evaluation(num_examples=2835, accuracy=0.9115692107320664, loss=0.2928183902153445, rmse=None, ndcg=None, aucs=None, auuc=None, qini=None)

# %%
logs = model.make_inspector().training_logs()

plt.figure(figsize=(12, 4))
plt.subplot(1, 2, 1)
plt.plot([log.num_trees for log in logs], [log.evaluation.accuracy for log in logs])
plt.xlabel("Number of trees")
plt.ylabel("Accuracy (out-of-bag)")
plt.subplot(1, 2, 2)
plt.plot([log.num_trees for log in logs], [log.evaluation.loss for log in logs])
plt.xlabel("Number of trees")
plt.ylabel("Logloss (out-of-bag)")
plt.show()

# %% [markdown]
# Calculate the score of our hold-out validation dataset

# %%
predictions = model.predict(val_ds)
y_true      = validation_data["label"]

from sklearn.metrics import roc_auc_score
ROC_AUC = roc_auc_score(y_true, predictions)
print("The ROC AUC score is %.5f" % ROC_AUC )
# Out:
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 69ms/step
# The ROC AUC score is 0.98011

# %%
# Compute binary classification metrics with sklearn
import numpy as np
from sklearn.metrics import (
    accuracy_score,
    precision_score,
    recall_score,
    f1_score,
    roc_auc_score,
    average_precision_score,
    confusion_matrix,
    classification_report,
    matthews_corrcoef,
    log_loss,
    brier_score_loss,
)

# Get predictions (probabilities or class labels)
preds = model.predict(test_ds)
# If model outputs probabilities, convert to labels by threshold 0.5
if preds.ndim == 2:
    # For TFDF classification, preds may be class probabilities with shape (N, 2)
    if preds.shape[1] == 2:
        pos_probs = preds[:, 1]
    else:
        # If single-probability column (positive class)
        pos_probs = preds[:, -1]
    y_pred = (pos_probs >= 0.5).astype(int)
else:
    # Already class labels
    y_pred = preds.astype(int)
    pos_probs = None

# Ground truth labels (must be 0/1 integers)
y_true = test_data["label"].astype(int).to_numpy()

# Core metrics
metrics = {}
metrics["accuracy"] = accuracy_score(y_true, y_pred)
metrics["precision"] = precision_score(y_true, y_pred, zero_division=0)
metrics["recall"] = recall_score(y_true, y_pred, zero_division=0)
metrics["f1"] = f1_score(y_true, y_pred, zero_division=0)
metrics["mcc"] = matthews_corrcoef(y_true, y_pred)

# Probabilistic metrics (only if we have probabilities)
if pos_probs is not None:
    metrics["roc_auc"] = roc_auc_score(y_true, pos_probs)
    metrics["pr_auc"] = average_precision_score(y_true, pos_probs)
    metrics["log_loss"] = log_loss(y_true, pos_probs, labels=[0,1])
    metrics["brier_score"] = brier_score_loss(y_true, pos_probs)

# Confusion matrix and detailed report
cm = confusion_matrix(y_true, y_pred, labels=[0,1])
report = classification_report(y_true, y_pred, digits=4)

print("Sklearn binary metrics:")
for k, v in metrics.items():
    print(f"{k}: {v:.4f}")
print("\nConfusion matrix:\n", cm)
print("\nClassification report:\n", report)
# Out:
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 80ms/step
# Sklearn binary metrics:
# accuracy: 0.9581
# precision: 0.8211
# recall: 0.8938
# f1: 0.8559
# mcc: 0.8325
# roc_auc: 0.9863
# pr_auc: 0.9351
# log_loss: 0.1245
# brier_score: 0.0316
#
# Confusion matrix:
#  [[676  22]
#  [ 12 101]]
#
# Classification report:
#                precision    recall  f1-score   support
#
#            0     0.9826    0.9685    0.9755       698
#            1     0.8211    0.8938    0.8559       113
#
#     accuracy                         0.9581       811
#    macro avg     0.9018    0.9311    0.9157       811
# weighted avg     0.9601    0.9581    0.9588       811
