# %%
# Import packages and modules
import numpy  as np
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow_decision_forests as tfdf

from sklearn.model_selection import train_test_split
# Out:
# 2026-08-13 04:22:03.495492: I tensorflow/core/util/port.cc:113] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2026-08-13 04:22:03.869795: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2026-08-13 04:22:09.108530: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
# Check the version of TensorFlow Decision Forests
print("Found TensorFlow Decision Forests v" + tfdf.__version__)
# Out:
# Found TensorFlow Decision Forests v1.9.1

# %%
datasetPath = 'dataset/firstorder/kernel5/dataset.csv'

# %%
# Parameters
datasetPath = "dataset/firstorder/kernel3/1.dataset.csv"

# %%
# train/validation/test = 70/10/20
dataset = pd.read_csv(datasetPath)

train_data, temp_data = train_test_split(dataset, test_size=0.3, random_state=42)
validation_data, test_data = train_test_split(temp_data, test_size=2/3, random_state=42)

# %%
from sklearn.utils.class_weight import compute_class_weight

# tinh class weight tren tap train
classes = np.array([0, 1])
weights = compute_class_weight(class_weight="balanced", classes=classes, y=train_data["label"])
class_weight = {0: weights[0], 1: weights[1]}

# gan sample_weight cho tung dong
train_data["sample_weight"] = train_data["label"].map(class_weight)
validation_data["sample_weight"] = validation_data["label"].map(class_weight)
test_data["sample_weight"] = test_data["label"].map(class_weight)

# Convert the dataset into a TensorFlow dataset.
train_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    train_data, label="label", weight="sample_weight"
)         
val_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    validation_data, label="label", weight="sample_weight"
)
test_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    test_data, label="label", weight="sample_weight"
)
# Out:
# 2026-08-13 04:22:22.803604: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:984] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2026-08-13 04:22:22.805268: W tensorflow/core/common_runtime/gpu/gpu_device.cc:2251] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...

# %%
import keras

# %%
# %%time

# Train a Random Forest model.
model = tfdf.keras.RandomForestModel()

# Add evaluation metrics
model.compile(
    metrics=["accuracy"]
)
model.fit(x=train_ds)

# # Train a Gradient Boosted Trees model.
# model = tfdf.keras.GradientBoostedTreesModel(num_trees=1500)
# model.fit(train_ds)
# Out:
# Use /tmp/tmpndu5yfc1 as temporary training directory
# Reading training dataset...
# Training dataset read in 0:00:02.705712. Found 2835 examples.
# Training model...
# Model trained in 0:00:00.212327
# Compiling model...
# [INFO 26-08-13 04:22:25.8466 UTC kernel.cc:1233] Loading model from path /tmp/tmpndu5yfc1/model/ with prefix 96c2a7768b7f4f1a
# [INFO 26-08-13 04:22:25.8955 UTC decision_forest.cc:734] Model loaded with 300 root(s), 34074 node(s), and 18 input feature(s).
# [INFO 26-08-13 04:22:25.8955 UTC abstract_model.cc:1362] Engine "RandomForestOptPred" built
# [INFO 26-08-13 04:22:25.8956 UTC kernel.cc:1061] Use fast generic engine
# Model compiled.
# CPU times: user 6.67 s, sys: 185 ms, total: 6.85 s
# Wall time: 6.25 s

# %%
# Evaluate the model
evaluate = model.evaluate(val_ds, return_dict=True)
print()

for name, value in evaluate.items():
    print(f"{name}: {value:.4f}")
# Out:
# WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 1/1 [==============================] - ETA: 0s - loss: 0.0000e+00 - accuracy: 0.9407
# 1/1 [==============================] - 3s 3s/step - loss: 0.0000e+00 - accuracy: 0.9407
# loss: 0.0000
# accuracy: 0.9407

# %%
# Model Summary
model.summary()
# Out:
# Model: "random_forest_model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
# =================================================================
# Total params: 1 (1.00 Byte)
# Trainable params: 0 (0.00 Byte)
# Non-trainable params: 1 (1.00 Byte)
# _________________________________________________________________
# Type: "RANDOM_FOREST"
# Task: CLASSIFICATION
# Label: "__LABEL"
#
# Input Features (18):
# 	10Percentile
# 	90Percentile
# 	Energy
# 	Entropy
# 	InterquartileRange
# 	Kurtosis
# 	Maximum
# 	Mean
# 	MeanAbsoluteDeviation
# 	Median
# 	Minimum
# 	Range
# 	RobustMeanAbsoluteDeviation
# 	RootMeanSquared
# 	Skewness
# 	TotalEnergy
# 	Uniformity
# 	Variance
#
# Trained with weights
#
# Variable Importance: INV_MEAN_MIN_DEPTH:
#     1.                      "Energy"  0.182631 ################
#     2.             "RootMeanSquared"  0.177673 ##############
#     3.                 "TotalEnergy"  0.176435 ##############
#     4.                        "Mean"  0.173771 #############
#     5.                      "Median"  0.170795 ############
#     6.                "10Percentile"  0.161692 ##########
#     7.                  "Uniformity"  0.159142 #########
#     8.          "InterquartileRange"  0.148772 ######
#     9.                "90Percentile"  0.144633 #####
#    10.                     "Entropy"  0.143943 ####
#    11. "RobustMeanAbsoluteDeviation"  0.136886 ##
#    12.                     "Maximum"  0.136624 ##
#    13.                     "Minimum"  0.136120 ##
#    14.       "MeanAbsoluteDeviation"  0.130693 #
#    15.                    "Skewness"  0.129642
#    16.                    "Kurtosis"  0.128554
#    17.                       "Range"  0.126666
#    18.                    "Variance"  0.126482
#
# Variable Importance: NUM_AS_ROOT:
#     1.                  "Mean" 59.000000 ################
#     2.                "Energy" 57.000000 ###############
#     3.           "TotalEnergy" 56.000000 ###############
#     4.       "RootMeanSquared" 50.000000 #############
#     5.                "Median" 39.000000 ##########
#     6.          "10Percentile" 20.000000 #####
#     7.          "90Percentile" 10.000000 ##
#     8.               "Minimum"  4.000000
#     9.               "Maximum"  2.000000
#    10.               "Entropy"  1.000000
#    11.              "Kurtosis"  1.000000
#    12. "MeanAbsoluteDeviation"  1.000000
#
# Variable Importance: NUM_NODES:
#     1.                  "Uniformity" 1278.000000 ################
#     2.                      "Median" 1263.000000 ###############
#     3.          "InterquartileRange" 1121.000000 ###########
#     4.                    "Skewness" 1009.000000 ########
#     5.                "10Percentile" 978.000000 ########
#     6.                     "Maximum" 958.000000 #######
#     7.                        "Mean" 947.000000 #######
#     8. "RobustMeanAbsoluteDeviation" 939.000000 #######
#     9.                     "Entropy" 935.000000 #######
#    10.                    "Kurtosis" 916.000000 ######
#    11.                "90Percentile" 914.000000 ######
#    12.                     "Minimum" 894.000000 #####
#    13.             "RootMeanSquared" 877.000000 #####
#    14.                 "TotalEnergy" 873.000000 #####
#    15.                      "Energy" 840.000000 ####
#    16.                       "Range" 792.000000 ###
#    17.       "MeanAbsoluteDeviation" 686.000000
#    18.                    "Variance" 667.000000
#
# Variable Importance: SUM_SCORE:
#     1.                        "Mean" 82912.138393 ################
#     2.                      "Energy" 81781.268189 ###############
#     3.                 "TotalEnergy" 77208.732334 ##############
#     4.             "RootMeanSquared" 73405.800582 ##############
#     5.                      "Median" 64882.382432 ############
#     6.                "10Percentile" 39416.719782 #######
#     7.                  "Uniformity" 20394.268030 ###
#     8.                "90Percentile" 19721.911627 ##
#     9.          "InterquartileRange" 14582.665368 #
#    10.                     "Entropy" 14264.802846 #
#    11.                     "Minimum" 13316.369699 #
#    12.                     "Maximum" 11705.278162 #
#    13. "RobustMeanAbsoluteDeviation" 9865.131789
#    14.                    "Skewness" 8004.662525
#    15.                    "Kurtosis" 7836.850508
#    16.       "MeanAbsoluteDeviation" 6459.311236
#    17.                       "Range" 6442.596306
#    18.                    "Variance" 5475.908717
#
#
#
# Winner takes all: true
# Out-of-bag evaluation: accuracy:0.906796 logloss:0.352836
# Number of trees: 300
# Total number of nodes: 34074
#
# Number of nodes by tree:
# Count: 300 Average: 113.58 StdDev: 8.97238
# Min: 81 Max: 141 Ignored: 0
# ----------------------------------------------
# [  81,  84)  1   0.33%   0.33%
# [  84,  87)  0   0.00%   0.33%
# [  87,  90)  1   0.33%   0.67%
# [  90,  93)  2   0.67%   1.33%
# [  93,  96)  3   1.00%   2.33% #
# [  96,  99)  4   1.33%   3.67% #
# [  99, 102) 16   5.33%   9.00% ###
# [ 102, 105) 11   3.67%  12.67% ##
# [ 105, 108) 46  15.33%  28.00% ########
# [ 108, 111) 19   6.33%  34.33% ###
# [ 111, 114) 51  17.00%  51.33% #########
# [ 114, 117) 24   8.00%  59.33% ####
# [ 117, 120) 56  18.67%  78.00% ##########
# [ 120, 123) 18   6.00%  84.00% ###
# [ 123, 126) 27   9.00%  93.00% #####
# [ 126, 129)  8   2.67%  95.67% #
# [ 129, 132)  6   2.00%  97.67% #
# [ 132, 135)  1   0.33%  98.00%
# [ 135, 138)  2   0.67%  98.67%
# [ 138, 141]  4   1.33% 100.00% #
#
# Depth by leafs:
# Count: 17187 Average: 7.44958 StdDev: 2.35929
# Min: 2 Max: 15 Ignored: 0
# ----------------------------------------------
# [  2,  3)  111   0.65%   0.65%
# [  3,  4)  522   3.04%   3.68% ##
# [  4,  5) 1099   6.39%  10.08% ####
# [  5,  6) 1845  10.73%  20.81% ######
# [  6,  7) 2668  15.52%  36.34% #########
# [  7,  8) 2859  16.63%  52.97% ##########
# [  8,  9) 2647  15.40%  68.37% #########
# [  9, 10) 2167  12.61%  80.98% ########
# [ 10, 11) 1508   8.77%  89.75% #####
# [ 11, 12)  894   5.20%  94.96% ###
# [ 12, 13)  463   2.69%  97.65% ##
# [ 13, 14)  249   1.45%  99.10% #
# [ 14, 15)  105   0.61%  99.71%
# [ 15, 15]   50   0.29% 100.00%
#
# Number of training obs by leaf:
# Count: 17187 Average: 49.4851 StdDev: 155.006
# Min: 5 Max: 1809 Ignored: 0
# ----------------------------------------------
# [    5,   95) 15557  90.52%  90.52% ##########
# [   95,  185)   526   3.06%  93.58%
# [  185,  275)   414   2.41%  95.99%
# [  275,  366)   129   0.75%  96.74%
# [  366,  456)    69   0.40%  97.14%
# [  456,  546)    90   0.52%  97.66%
# [  546,  636)    58   0.34%  98.00%
# [  636,  727)    68   0.40%  98.39%
# [  727,  817)    54   0.31%  98.71%
# [  817,  907)    48   0.28%  98.99%
# [  907,  997)    21   0.12%  99.11%
# [  997, 1088)    32   0.19%  99.30%
# [ 1088, 1178)    30   0.17%  99.47%
# [ 1178, 1268)    41   0.24%  99.71%
# [ 1268, 1358)    28   0.16%  99.87%
# [ 1358, 1449)     7   0.04%  99.91%
# [ 1449, 1539)     9   0.05%  99.97%
# [ 1539, 1629)     3   0.02%  99.98%
# [ 1629, 1719)     2   0.01%  99.99%
# [ 1719, 1809]     1   0.01% 100.00%
#
# Attribute in nodes:
# 	1278 : Uniformity [NUMERICAL]
# 	1263 : Median [NUMERICAL]
# 	1121 : InterquartileRange [NUMERICAL]
# 	1009 : Skewness [NUMERICAL]
# 	978 : 10Percentile [NUMERICAL]
# 	958 : Maximum [NUMERICAL]
# 	947 : Mean [NUMERICAL]
# 	939 : RobustMeanAbsoluteDeviation [NUMERICAL]
# 	935 : Entropy [NUMERICAL]
# 	916 : Kurtosis [NUMERICAL]
# 	914 : 90Percentile [NUMERICAL]
# 	894 : Minimum [NUMERICAL]
# 	877 : RootMeanSquared [NUMERICAL]
# 	873 : TotalEnergy [NUMERICAL]
# 	840 : Energy [NUMERICAL]
# 	792 : Range [NUMERICAL]
# 	686 : MeanAbsoluteDeviation [NUMERICAL]
# 	667 : Variance [NUMERICAL]
#
# Attribute in nodes with depth <= 0:
# 	59 : Mean [NUMERICAL]
# 	57 : Energy [NUMERICAL]
# 	56 : TotalEnergy [NUMERICAL]
# 	50 : RootMeanSquared [NUMERICAL]
# 	39 : Median [NUMERICAL]
# 	20 : 10Percentile [NUMERICAL]
# 	10 : 90Percentile [NUMERICAL]
# 	4 : Minimum [NUMERICAL]
# 	2 : Maximum [NUMERICAL]
# 	1 : MeanAbsoluteDeviation [NUMERICAL]
# 	1 : Kurtosis [NUMERICAL]
# 	1 : Entropy [NUMERICAL]
#
# Attribute in nodes with depth <= 1:
# 	148 : Energy [NUMERICAL]
# 	134 : RootMeanSquared [NUMERICAL]
# 	128 : TotalEnergy [NUMERICAL]
# 	123 : Mean [NUMERICAL]
# 	104 : Median [NUMERICAL]
# 	96 : 10Percentile [NUMERICAL]
# 	58 : 90Percentile [NUMERICAL]
# 	40 : Entropy [NUMERICAL]
# 	27 : Maximum [NUMERICAL]
# 	25 : Minimum [NUMERICAL]
# 	12 : Uniformity [NUMERICAL]
# 	1 : Skewness [NUMERICAL]
# 	1 : Range [NUMERICAL]
# 	1 : MeanAbsoluteDeviation [NUMERICAL]
# 	1 : Kurtosis [NUMERICAL]
# 	1 : InterquartileRange [NUMERICAL]
#
# Attribute in nodes with depth <= 2:
# 	219 : Energy [NUMERICAL]
# 	206 : Mean [NUMERICAL]
# 	200 : Median [NUMERICAL]
# 	192 : RootMeanSquared [NUMERICAL]
# 	192 : 10Percentile [NUMERICAL]
# 	191 : TotalEnergy [NUMERICAL]
# 	164 : Uniformity [NUMERICAL]
# 	124 : Entropy [NUMERICAL]
# 	111 : 90Percentile [NUMERICAL]
# 	81 : InterquartileRange [NUMERICAL]
# 	77 : Maximum [NUMERICAL]
# 	73 : Minimum [NUMERICAL]
# 	48 : RobustMeanAbsoluteDeviation [NUMERICAL]
# 	31 : Skewness [NUMERICAL]
# 	28 : MeanAbsoluteDeviation [NUMERICAL]
# 	21 : Range [NUMERICAL]
# 	16 : Kurtosis [NUMERICAL]
# 	15 : Variance [NUMERICAL]
#
# Attribute in nodes with depth <= 3:
# 	362 : Uniformity [NUMERICAL]
# 	317 : Median [NUMERICAL]
# 	298 : Energy [NUMERICAL]
# 	294 : Mean [NUMERICAL]
# 	286 : 10Percentile [NUMERICAL]
# 	280 : RootMeanSquared [NUMERICAL]
# 	268 : TotalEnergy [NUMERICAL]
# 	255 : InterquartileRange [NUMERICAL]
# 	221 : Entropy [NUMERICAL]
# 	175 : 90Percentile [NUMERICAL]
# 	169 : Minimum [NUMERICAL]
# 	160 : RobustMeanAbsoluteDeviation [NUMERICAL]
# 	157 : Maximum [NUMERICAL]
# 	98 : Skewness [NUMERICAL]
# 	92 : MeanAbsoluteDeviation [NUMERICAL]
# 	85 : Range [NUMERICAL]
# 	64 : Variance [NUMERICAL]
# 	64 : Kurtosis [NUMERICAL]
#
# Attribute in nodes with depth <= 5:
# 	737 : Uniformity [NUMERICAL]
# 	697 : Median [NUMERICAL]
# 	589 : InterquartileRange [NUMERICAL]
# 	524 : 10Percentile [NUMERICAL]
# 	522 : Mean [NUMERICAL]
# 	518 : TotalEnergy [NUMERICAL]
# 	513 : RootMeanSquared [NUMERICAL]
# 	495 : Energy [NUMERICAL]
# 	480 : Entropy [NUMERICAL]
# 	451 : 90Percentile [NUMERICAL]
# 	449 : RobustMeanAbsoluteDeviation [NUMERICAL]
# 	449 : Maximum [NUMERICAL]
# 	407 : Skewness [NUMERICAL]
# 	400 : Minimum [NUMERICAL]
# 	346 : Kurtosis [NUMERICAL]
# 	299 : Range [NUMERICAL]
# 	294 : MeanAbsoluteDeviation [NUMERICAL]
# 	269 : Variance [NUMERICAL]
#
# Condition type in nodes:
# 	16887 : HigherCondition
# Condition type in nodes with depth <= 0:
# 	300 : HigherCondition
# Condition type in nodes with depth <= 1:
# 	900 : HigherCondition
# Condition type in nodes with depth <= 2:
# 	1989 : HigherCondition
# Condition type in nodes with depth <= 3:
# 	3645 : HigherCondition
# Condition type in nodes with depth <= 5:
# 	8439 : HigherCondition
# Node format: NOT_SET
#
# Training OOB:
# 	trees: 1, Out-of-bag evaluation: accuracy:0.875461 logloss:4.48884
# 	trees: 12, Out-of-bag evaluation: accuracy:0.890394 logloss:2.28039
# 	trees: 22, Out-of-bag evaluation: accuracy:0.905112 logloss:1.046
# 	trees: 32, Out-of-bag evaluation: accuracy:0.903741 logloss:0.843955
# 	trees: 42, Out-of-bag evaluation: accuracy:0.905221 logloss:0.627889
# 	trees: 52, Out-of-bag evaluation: accuracy:0.907363 logloss:0.615506
# 	trees: 62, Out-of-bag evaluation: accuracy:0.908229 logloss:0.564693
# 	trees: 72, Out-of-bag evaluation: accuracy:0.905883 logloss:0.563026
# 	trees: 82, Out-of-bag evaluation: accuracy:0.902466 logloss:0.523193
# 	trees: 92, Out-of-bag evaluation: accuracy:0.903332 logloss:0.523131
# 	trees: 102, Out-of-bag evaluation: accuracy:0.903127 logloss:0.521275
# 	trees: 112, Out-of-bag evaluation: accuracy:0.900576 logloss:0.477285
# 	trees: 122, Out-of-bag evaluation: accuracy:0.900371 logloss:0.397227
# 	trees: 132, Out-of-bag evaluation: accuracy:0.903332 logloss:0.39657
# 	trees: 142, Out-of-bag evaluation: accuracy:0.906087 logloss:0.398215
# 	trees: 152, Out-of-bag evaluation: accuracy:0.903127 logloss:0.397673
# 	trees: 163, Out-of-bag evaluation: accuracy:0.903127 logloss:0.395989
# 	trees: 173, Out-of-bag evaluation: accuracy:0.906749 logloss:0.394954
# 	trees: 183, Out-of-bag evaluation: accuracy:0.904655 logloss:0.395293
# 	trees: 193, Out-of-bag evaluation: accuracy:0.903379 logloss:0.395051
# 	trees: 203, Out-of-bag evaluation: accuracy:0.902308 logloss:0.355017
# 	trees: 213, Out-of-bag evaluation: accuracy:0.906544 logloss:0.353673
# 	trees: 223, Out-of-bag evaluation: accuracy:0.904655 logloss:0.354018
# 	trees: 233, Out-of-bag evaluation: accuracy:0.907206 logloss:0.354103
# 	trees: 243, Out-of-bag evaluation: accuracy:0.90593 logloss:0.354635
# 	trees: 253, Out-of-bag evaluation: accuracy:0.90593 logloss:0.353738
# 	trees: 263, Out-of-bag evaluation: accuracy:0.905521 logloss:0.352598
# 	trees: 274, Out-of-bag evaluation: accuracy:0.906387 logloss:0.352789
# 	trees: 284, Out-of-bag evaluation: accuracy:0.905726 logloss:0.352757
# 	trees: 294, Out-of-bag evaluation: accuracy:0.907206 logloss:0.353149
# 	trees: 300, Out-of-bag evaluation: accuracy:0.906796 logloss:0.352836

# %%
# Model features
model.make_inspector().features()
# Out:
# ["10Percentile" (1; #0),
#  "90Percentile" (1; #1),
#  "Energy" (1; #2),
#  "Entropy" (1; #3),
#  "InterquartileRange" (1; #4),
#  "Kurtosis" (1; #5),
#  "Maximum" (1; #6),
#  "Mean" (1; #7),
#  "MeanAbsoluteDeviation" (1; #8),
#  "Median" (1; #9),
#  "Minimum" (1; #10),
#  "Range" (1; #11),
#  "RobustMeanAbsoluteDeviation" (1; #12),
#  "RootMeanSquared" (1; #13),
#  "Skewness" (1; #14),
#  "TotalEnergy" (1; #15),
#  "Uniformity" (1; #16),
#  "Variance" (1; #17)]

# %%
# Feature importance
model.make_inspector().variable_importances()
# Out:
# {'INV_MEAN_MIN_DEPTH': [("Energy" (1; #2), 0.18263090441520907),
#   ("RootMeanSquared" (1; #13), 0.17767290670604927),
#   ("TotalEnergy" (1; #15), 0.17643510874845025),
#   ("Mean" (1; #7), 0.1737706723118968),
#   ("Median" (1; #9), 0.17079489886615787),
#   ("10Percentile" (1; #0), 0.1616921132337277),
#   ("Uniformity" (1; #16), 0.15914227220076238),
#   ("InterquartileRange" (1; #4), 0.14877214039443473),
#   ("90Percentile" (1; #1), 0.14463332530956757),
#   ("Entropy" (1; #3), 0.14394307931135936),
#   ("RobustMeanAbsoluteDeviation" (1; #12), 0.13688630409048633),
#   ("Maximum" (1; #6), 0.13662380181976433),
#   ("Minimum" (1; #10), 0.13611951368547917),
#   ("MeanAbsoluteDeviation" (1; #8), 0.1306926126461281),
#   ("Skewness" (1; #14), 0.12964214398275772),
#   ("Kurtosis" (1; #5), 0.128553629087884),
#   ("Range" (1; #11), 0.12666555189455475),
#   ("Variance" (1; #17), 0.1264816368237811)],
#  'SUM_SCORE': [("Mean" (1; #7), 82912.13839319402),
#   ("Energy" (1; #2), 81781.26818923456),
#   ("TotalEnergy" (1; #15), 77208.73233439843),
#   ("RootMeanSquared" (1; #13), 73405.80058162012),
#   ("Median" (1; #9), 64882.382431981656),
#   ("10Percentile" (1; #0), 39416.71978236026),
#   ("Uniformity" (1; #16), 20394.268030455514),
#   ("90Percentile" (1; #1), 19721.911627147438),
#   ("InterquartileRange" (1; #4), 14582.665368227335),
#   ("Entropy" (1; #3), 14264.802845638826),
#   ("Minimum" (1; #10), 13316.369699359768),
#   ("Maximum" (1; #6), 11705.278162467612),
#   ("RobustMeanAbsoluteDeviation" (1; #12), 9865.131788878074),
#   ("Skewness" (1; #14), 8004.662524835438),
#   ("Kurtosis" (1; #5), 7836.850508304752),
#   ("MeanAbsoluteDeviation" (1; #8), 6459.311236438349),
#   ("Range" (1; #11), 6442.59630575626),
#   ("Variance" (1; #17), 5475.908717022123)],
#  'NUM_AS_ROOT': [("Mean" (1; #7), 59.0),
#   ("Energy" (1; #2), 57.0),
#   ("TotalEnergy" (1; #15), 56.0),
#   ("RootMeanSquared" (1; #13), 50.0),
#   ("Median" (1; #9), 39.0),
#   ("10Percentile" (1; #0), 20.0),
#   ("90Percentile" (1; #1), 10.0),
#   ("Minimum" (1; #10), 4.0),
#   ("Maximum" (1; #6), 2.0),
#   ("Entropy" (1; #3), 1.0),
#   ("Kurtosis" (1; #5), 1.0),
#   ("MeanAbsoluteDeviation" (1; #8), 1.0)],
#  'NUM_NODES': [("Uniformity" (1; #16), 1278.0),
#   ("Median" (1; #9), 1263.0),
#   ("InterquartileRange" (1; #4), 1121.0),
#   ("Skewness" (1; #14), 1009.0),
#   ("10Percentile" (1; #0), 978.0),
#   ("Maximum" (1; #6), 958.0),
#   ("Mean" (1; #7), 947.0),
#   ("RobustMeanAbsoluteDeviation" (1; #12), 939.0),
#   ("Entropy" (1; #3), 935.0),
#   ("Kurtosis" (1; #5), 916.0),
#   ("90Percentile" (1; #1), 914.0),
#   ("Minimum" (1; #10), 894.0),
#   ("RootMeanSquared" (1; #13), 877.0),
#   ("TotalEnergy" (1; #15), 873.0),
#   ("Energy" (1; #2), 840.0),
#   ("Range" (1; #11), 792.0),
#   ("MeanAbsoluteDeviation" (1; #8), 686.0),
#   ("Variance" (1; #17), 667.0)]}

# %%
# Model self evaluation
model.make_inspector().evaluation()
# Out:
# Evaluation(num_examples=2835, accuracy=0.9067963856695543, loss=0.3528357414114226, rmse=None, ndcg=None, aucs=None, auuc=None, qini=None)

# %%
logs = model.make_inspector().training_logs()

plt.figure(figsize=(12, 4))
plt.subplot(1, 2, 1)
plt.plot([log.num_trees for log in logs], [log.evaluation.accuracy for log in logs])
plt.xlabel("Number of trees")
plt.ylabel("Accuracy (out-of-bag)")
plt.subplot(1, 2, 2)
plt.plot([log.num_trees for log in logs], [log.evaluation.loss for log in logs])
plt.xlabel("Number of trees")
plt.ylabel("Logloss (out-of-bag)")
plt.show()

# %% [markdown]
# Calculate the score of our hold-out validation dataset

# %%
predictions = model.predict(val_ds)
y_true      = validation_data["label"]

from sklearn.metrics import roc_auc_score
ROC_AUC = roc_auc_score(y_true, predictions)
print("The ROC AUC score is %.5f" % ROC_AUC )
# Out:
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 69ms/step
# The ROC AUC score is 0.97310

# %%
# Compute binary classification metrics with sklearn
import numpy as np
from sklearn.metrics import (
    accuracy_score,
    precision_score,
    recall_score,
    f1_score,
    roc_auc_score,
    average_precision_score,
    confusion_matrix,
    classification_report,
    matthews_corrcoef,
    log_loss,
    brier_score_loss,
)

# Get predictions (probabilities or class labels)
preds = model.predict(test_ds)
# If model outputs probabilities, convert to labels by threshold 0.5
if preds.ndim == 2:
    # For TFDF classification, preds may be class probabilities with shape (N, 2)
    if preds.shape[1] == 2:
        pos_probs = preds[:, 1]
    else:
        # If single-probability column (positive class)
        pos_probs = preds[:, -1]
    y_pred = (pos_probs >= 0.5).astype(int)
else:
    # Already class labels
    y_pred = preds.astype(int)
    pos_probs = None

# Ground truth labels (must be 0/1 integers)
y_true = test_data["label"].astype(int).to_numpy()

# Core metrics
metrics = {}
metrics["accuracy"] = accuracy_score(y_true, y_pred)
metrics["precision"] = precision_score(y_true, y_pred, zero_division=0)
metrics["recall"] = recall_score(y_true, y_pred, zero_division=0)
metrics["f1"] = f1_score(y_true, y_pred, zero_division=0)
metrics["mcc"] = matthews_corrcoef(y_true, y_pred)

# Probabilistic metrics (only if we have probabilities)
if pos_probs is not None:
    metrics["roc_auc"] = roc_auc_score(y_true, pos_probs)
    metrics["pr_auc"] = average_precision_score(y_true, pos_probs)
    metrics["log_loss"] = log_loss(y_true, pos_probs, labels=[0,1])
    metrics["brier_score"] = brier_score_loss(y_true, pos_probs)

# Confusion matrix and detailed report
cm = confusion_matrix(y_true, y_pred, labels=[0,1])
report = classification_report(y_true, y_pred, digits=4)

print("Sklearn binary metrics:")
for k, v in metrics.items():
    print(f"{k}: {v:.4f}")
print("\nConfusion matrix:\n", cm)
print("\nClassification report:\n", report)
# Out:
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 82ms/step
# Sklearn binary metrics:
# accuracy: 0.9420
# precision: 0.8036
# recall: 0.7826
# f1: 0.7930
# mcc: 0.7594
# roc_auc: 0.9599
# pr_auc: 0.8796
# log_loss: 0.1776
# brier_score: 0.0423
#
# Confusion matrix:
#  [[674  22]
#  [ 25  90]]
#
# Classification report:
#                precision    recall  f1-score   support
#
#            0     0.9642    0.9684    0.9663       696
#            1     0.8036    0.7826    0.7930       115
#
#     accuracy                         0.9420       811
#    macro avg     0.8839    0.8755    0.8796       811
# weighted avg     0.9415    0.9420    0.9417       811
