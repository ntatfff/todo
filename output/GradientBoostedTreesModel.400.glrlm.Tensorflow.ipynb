# %%
# Import packages and modules
import numpy  as np
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow_decision_forests as tfdf

from sklearn.model_selection import train_test_split
# Out:
# 2026-07-04 08:49:47.069246: I tensorflow/core/util/port.cc:113] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2026-07-04 08:49:47.108823: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2026-07-04 08:49:51.391889: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
# Check the version of TensorFlow Decision Forests
print("Found TensorFlow Decision Forests v" + tfdf.__version__)
# Out:
# Found TensorFlow Decision Forests v1.9.1

# %%
datasetPath = 'dataset/firstorder/kernel5-radius5/dataset.csv'

# %%
# Parameters
datasetPath = "dataset/glrlm/kernel5-radius5/400.dataset.csv"

# %%
# train/validation/test = 70/10/20
dataset = pd.read_csv(datasetPath)

train_data, temp_data = train_test_split(dataset, test_size=0.3, random_state=42)
validation_data, test_data = train_test_split(temp_data, test_size=2/3, random_state=42)

# %%
from sklearn.utils.class_weight import compute_class_weight

# tinh class weight tren tap train
classes = np.array([0, 1])
weights = compute_class_weight(class_weight="balanced", classes=classes, y=train_data["label"])
class_weight = {0: weights[0], 1: weights[1]}

# gan sample_weight cho tung dong
train_data["sample_weight"] = train_data["label"].map(class_weight)
validation_data["sample_weight"] = validation_data["label"].map(class_weight)
test_data["sample_weight"] = test_data["label"].map(class_weight)

# Convert the dataset into a TensorFlow dataset.
train_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    train_data, label="label", weight="sample_weight"
)         
val_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    validation_data, label="label", weight="sample_weight"
)
test_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    test_data, label="label", weight="sample_weight"
)
# Out:
# 2026-07-04 08:50:05.562839: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:984] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2026-07-04 08:50:05.564853: W tensorflow/core/common_runtime/gpu/gpu_device.cc:2251] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...

# %%
import keras

# %%
# %%time

# Train a Gradient Boosted Trees model.
model = tfdf.keras.GradientBoostedTreesModel()

# Add evaluation metrics
model.compile(
    metrics=["accuracy"]
)
model.fit(x=train_ds)

# # Train a Gradient Boosted Trees model.
# model = tfdf.keras.GradientBoostedTreesModel(num_trees=1500)
# model.fit(train_ds)
# Out:
# Use /tmp/tmp8nslw_gr as temporary training directory
# [WARNING 26-07-04 08:50:05.7529 UTC gradient_boosted_trees.cc:1840] "goss_alpha" set but "sampling_method" not equal to "GOSS".
# [WARNING 26-07-04 08:50:05.7529 UTC gradient_boosted_trees.cc:1851] "goss_beta" set but "sampling_method" not equal to "GOSS".
# [WARNING 26-07-04 08:50:05.7529 UTC gradient_boosted_trees.cc:1865] "selective_gradient_boosting_ratio" set but "sampling_method" not equal to "SELGB".
# Reading training dataset...
# Training dataset read in 0:00:03.722917. Found 315452 examples.
# Training model...
# Model trained in 0:01:21.635037
# Compiling model...
# [INFO 26-07-04 08:51:31.1208 UTC kernel.cc:1233] Loading model from path /tmp/tmp8nslw_gr/model/ with prefix bc1b87c616f94ca5
# [INFO 26-07-04 08:51:31.1356 UTC quick_scorer_extended.cc:911] The binary was compiled without AVX2 support, but your CPU supports it. Enable it for faster model inference.
# [INFO 26-07-04 08:51:31.1367 UTC abstract_model.cc:1362] Engine "GradientBoostedTreesQuickScorerExtended" built
# [INFO 26-07-04 08:51:31.1367 UTC kernel.cc:1061] Use fast generic engine
# Model compiled.
# CPU times: user 10min 26s, sys: 4.56 s, total: 10min 31s
# Wall time: 1min 28s

# %%
# Evaluate the model
evaluate = model.evaluate(val_ds, return_dict=True)
print()

for name, value in evaluate.items():
    print(f"{name}: {value:.4f}")
# Out:
# WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
#  1/46 [..............................] - ETA: 2:11 - loss: 0.0000e+00 - accuracy: 0.8920
# 13/46 [=======>......................] - ETA: 0s - loss: 0.0000e+00 - accuracy: 0.8845
# 24/46 [==============>...............] - ETA: 0s - loss: 0.0000e+00 - accuracy: 0.8843
# 36/46 [======================>.......] - ETA: 0s - loss: 0.0000e+00 - accuracy: 0.8857
# 46/46 [==============================] - 3s 4ms/step - loss: 0.0000e+00 - accuracy: 0.8871
# loss: 0.0000
# accuracy: 0.8871

# %%
# Model Summary
model.summary()
# Out:
# Model: "gradient_boosted_trees_model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
# =================================================================
# Total params: 1 (1.00 Byte)
# Trainable params: 0 (0.00 Byte)
# Non-trainable params: 1 (1.00 Byte)
# _________________________________________________________________
# Type: "GRADIENT_BOOSTED_TREES"
# Task: CLASSIFICATION
# Label: "__LABEL"
#
# Input Features (16):
# 	GrayLevelNonUniformity
# 	GrayLevelNonUniformityNormalized
# 	GrayLevelVariance
# 	HighGrayLevelRunEmphasis
# 	LongRunEmphasis
# 	LongRunHighGrayLevelEmphasis
# 	LongRunLowGrayLevelEmphasis
# 	LowGrayLevelRunEmphasis
# 	RunEntropy
# 	RunLengthNonUniformity
# 	RunLengthNonUniformityNormalized
# 	RunPercentage
# 	RunVariance
# 	ShortRunEmphasis
# 	ShortRunHighGrayLevelEmphasis
# 	ShortRunLowGrayLevelEmphasis
#
# Trained with weights
#
# Variable Importance: INV_MEAN_MIN_DEPTH:
#     1.     "LongRunHighGrayLevelEmphasis"  0.239949 ################
#     2. "RunLengthNonUniformityNormalized"  0.231412 #############
#     3.           "GrayLevelNonUniformity"  0.218379 ##########
#     4.                       "RunEntropy"  0.205870 #######
#     5.     "ShortRunLowGrayLevelEmphasis"  0.202561 ######
#     6.                "GrayLevelVariance"  0.198173 #####
#     7.    "ShortRunHighGrayLevelEmphasis"  0.194163 ####
#     8.                 "ShortRunEmphasis"  0.192360 ####
#     9.      "LongRunLowGrayLevelEmphasis"  0.192324 ####
#    10.                      "RunVariance"  0.189049 ###
#    11.         "HighGrayLevelRunEmphasis"  0.184552 ##
#    12. "GrayLevelNonUniformityNormalized"  0.184252 ##
#    13.          "LowGrayLevelRunEmphasis"  0.184126 ##
#    14.           "RunLengthNonUniformity"  0.183613 ##
#    15.                  "LongRunEmphasis"  0.183135 #
#    16.                    "RunPercentage"  0.175541
#
# Variable Importance: NUM_AS_ROOT:
#     1. "RunLengthNonUniformityNormalized" 58.000000 ################
#     2.     "LongRunHighGrayLevelEmphasis" 53.000000 ##############
#     3.           "GrayLevelNonUniformity" 44.000000 ############
#     4.     "ShortRunLowGrayLevelEmphasis" 27.000000 #######
#     5.                 "ShortRunEmphasis" 20.000000 #####
#     6.      "LongRunLowGrayLevelEmphasis" 17.000000 ####
#     7.                       "RunEntropy" 17.000000 ####
#     8.          "LowGrayLevelRunEmphasis" 14.000000 ###
#     9.           "RunLengthNonUniformity" 13.000000 ###
#    10.         "HighGrayLevelRunEmphasis" 12.000000 ###
#    11.                "GrayLevelVariance"  7.000000 #
#    12.    "ShortRunHighGrayLevelEmphasis"  3.000000
#    13. "GrayLevelNonUniformityNormalized"  2.000000
#    14.                      "RunVariance"  1.000000
#
# Variable Importance: NUM_NODES:
#     1.     "LongRunHighGrayLevelEmphasis" 992.000000 ################
#     2.                       "RunEntropy" 763.000000 ###########
#     3.                "GrayLevelVariance" 745.000000 ##########
#     4.           "GrayLevelNonUniformity" 685.000000 #########
#     5.     "ShortRunLowGrayLevelEmphasis" 590.000000 #######
#     6.    "ShortRunHighGrayLevelEmphasis" 553.000000 ######
#     7.      "LongRunLowGrayLevelEmphasis" 525.000000 ######
#     8. "RunLengthNonUniformityNormalized" 525.000000 ######
#     9.                      "RunVariance" 436.000000 ####
#    10. "GrayLevelNonUniformityNormalized" 374.000000 ###
#    11.         "HighGrayLevelRunEmphasis" 349.000000 ##
#    12.                 "ShortRunEmphasis" 333.000000 ##
#    13.          "LowGrayLevelRunEmphasis" 327.000000 ##
#    14.                  "LongRunEmphasis" 299.000000 #
#    15.                    "RunPercentage" 235.000000
#    16.           "RunLengthNonUniformity" 212.000000
#
# Variable Importance: SUM_SCORE:
#     1.          "LowGrayLevelRunEmphasis" 51940.425282 ################
#     2.     "LongRunHighGrayLevelEmphasis" 46888.849375 ##############
#     3.     "ShortRunLowGrayLevelEmphasis" 40670.512304 ############
#     4.    "ShortRunHighGrayLevelEmphasis" 32984.706255 #########
#     5.                       "RunEntropy" 29194.262595 ########
#     6.           "GrayLevelNonUniformity" 14527.279565 ####
#     7.                      "RunVariance" 11099.441008 ##
#     8.                "GrayLevelVariance" 7524.750292 #
#     9.         "HighGrayLevelRunEmphasis" 7390.194391 #
#    10.      "LongRunLowGrayLevelEmphasis" 5919.397249 #
#    11. "RunLengthNonUniformityNormalized" 5236.905868 #
#    12.                 "ShortRunEmphasis" 3649.111224
#    13.                    "RunPercentage" 1968.170357
#    14.           "RunLengthNonUniformity" 1913.644783
#    15.                  "LongRunEmphasis" 1763.216883
#    16. "GrayLevelNonUniformityNormalized" 1742.113749
#
#
#
# Loss: BINOMIAL_LOG_LIKELIHOOD
# Validation loss value: 0.595104
# Number of trees per iteration: 1
# Node format: NOT_SET
# Number of trees: 288
# Total number of nodes: 16174
#
# Number of nodes by tree:
# Count: 288 Average: 56.1597 StdDev: 7.00016
# Min: 31 Max: 63 Ignored: 0
# ----------------------------------------------
# [ 31, 32)  1   0.35%   0.35%
# [ 32, 34)  1   0.35%   0.69%
# [ 34, 35)  0   0.00%   0.69%
# [ 35, 37)  2   0.69%   1.39%
# [ 37, 39)  1   0.35%   1.74%
# [ 39, 40)  4   1.39%   3.12% #
# [ 40, 42)  3   1.04%   4.17%
# [ 42, 44)  6   2.08%   6.25% #
# [ 44, 45)  0   0.00%   6.25%
# [ 45, 47) 10   3.47%   9.72% #
# [ 47, 49) 10   3.47%  13.19% #
# [ 49, 50) 24   8.33%  21.53% ###
# [ 50, 52) 14   4.86%  26.39% ##
# [ 52, 54) 21   7.29%  33.68% ###
# [ 54, 55)  0   0.00%  33.68%
# [ 55, 57) 18   6.25%  39.93% ##
# [ 57, 59) 26   9.03%  48.96% ####
# [ 59, 60) 22   7.64%  56.60% ###
# [ 60, 62) 51  17.71%  74.31% #######
# [ 62, 63] 74  25.69% 100.00% ##########
#
# Depth by leafs:
# Count: 8231 Average: 4.91702 StdDev: 0.370902
# Min: 2 Max: 5 Ignored: 0
# ----------------------------------------------
# [ 2, 3)   49   0.60%   0.60%
# [ 3, 4)  106   1.29%   1.88%
# [ 4, 5)  324   3.94%   5.82%
# [ 5, 5] 7752  94.18% 100.00% ##########
#
# Number of training obs by leaf:
# Count: 8231 Average: 9930.17 StdDev: 35236.2
# Min: 5 Max: 281494 Ignored: 0
# ----------------------------------------------
# [      5,  14079) 7298  88.66%  88.66% ##########
# [  14079,  28154)  369   4.48%  93.15% #
# [  28154,  42228)  129   1.57%  94.72%
# [  42228,  56303)   81   0.98%  95.70%
# [  56303,  70377)   41   0.50%  96.20%
# [  70377,  84452)   29   0.35%  96.55%
# [  84452,  98526)   37   0.45%  97.00%
# [  98526, 112601)   24   0.29%  97.29%
# [ 112601, 126675)   19   0.23%  97.52%
# [ 126675, 140750)   17   0.21%  97.73%
# [ 140750, 154824)   20   0.24%  97.97%
# [ 154824, 168899)   15   0.18%  98.15%
# [ 168899, 182973)   23   0.28%  98.43%
# [ 182973, 197048)   13   0.16%  98.59%
# [ 197048, 211122)   18   0.22%  98.81%
# [ 211122, 225197)    9   0.11%  98.92%
# [ 225197, 239271)   18   0.22%  99.14%
# [ 239271, 253346)   24   0.29%  99.43%
# [ 253346, 267420)   25   0.30%  99.73%
# [ 267420, 281494]   22   0.27% 100.00%
#
# Attribute in nodes:
# 	992 : LongRunHighGrayLevelEmphasis [NUMERICAL]
# 	763 : RunEntropy [NUMERICAL]
# 	745 : GrayLevelVariance [NUMERICAL]
# 	685 : GrayLevelNonUniformity [NUMERICAL]
# 	590 : ShortRunLowGrayLevelEmphasis [NUMERICAL]
# 	553 : ShortRunHighGrayLevelEmphasis [NUMERICAL]
# 	525 : RunLengthNonUniformityNormalized [NUMERICAL]
# 	525 : LongRunLowGrayLevelEmphasis [NUMERICAL]
# 	436 : RunVariance [NUMERICAL]
# 	374 : GrayLevelNonUniformityNormalized [NUMERICAL]
# 	349 : HighGrayLevelRunEmphasis [NUMERICAL]
# 	333 : ShortRunEmphasis [NUMERICAL]
# 	327 : LowGrayLevelRunEmphasis [NUMERICAL]
# 	299 : LongRunEmphasis [NUMERICAL]
# 	235 : RunPercentage [NUMERICAL]
# 	212 : RunLengthNonUniformity [NUMERICAL]
#
# Attribute in nodes with depth <= 0:
# 	58 : RunLengthNonUniformityNormalized [NUMERICAL]
# 	53 : LongRunHighGrayLevelEmphasis [NUMERICAL]
# 	44 : GrayLevelNonUniformity [NUMERICAL]
# 	27 : ShortRunLowGrayLevelEmphasis [NUMERICAL]
# 	20 : ShortRunEmphasis [NUMERICAL]
# 	17 : RunEntropy [NUMERICAL]
# 	17 : LongRunLowGrayLevelEmphasis [NUMERICAL]
# 	14 : LowGrayLevelRunEmphasis [NUMERICAL]
# 	13 : RunLengthNonUniformity [NUMERICAL]
# 	12 : HighGrayLevelRunEmphasis [NUMERICAL]
# 	7 : GrayLevelVariance [NUMERICAL]
# 	3 : ShortRunHighGrayLevelEmphasis [NUMERICAL]
# 	2 : GrayLevelNonUniformityNormalized [NUMERICAL]
# 	1 : RunVariance [NUMERICAL]
#
# Attribute in nodes with depth <= 1:
# 	132 : RunLengthNonUniformityNormalized [NUMERICAL]
# 	122 : LongRunHighGrayLevelEmphasis [NUMERICAL]
# 	82 : GrayLevelNonUniformity [NUMERICAL]
# 	79 : RunEntropy [NUMERICAL]
# 	59 : ShortRunHighGrayLevelEmphasis [NUMERICAL]
# 	53 : ShortRunLowGrayLevelEmphasis [NUMERICAL]
# 	52 : GrayLevelVariance [NUMERICAL]
# 	50 : RunVariance [NUMERICAL]
# 	47 : ShortRunEmphasis [NUMERICAL]
# 	42 : LongRunEmphasis [NUMERICAL]
# 	33 : LongRunLowGrayLevelEmphasis [NUMERICAL]
# 	30 : RunLengthNonUniformity [NUMERICAL]
# 	28 : HighGrayLevelRunEmphasis [NUMERICAL]
# 	24 : LowGrayLevelRunEmphasis [NUMERICAL]
# 	21 : GrayLevelNonUniformityNormalized [NUMERICAL]
# 	10 : RunPercentage [NUMERICAL]
#
# Attribute in nodes with depth <= 2:
# 	264 : LongRunHighGrayLevelEmphasis [NUMERICAL]
# 	195 : RunLengthNonUniformityNormalized [NUMERICAL]
# 	194 : GrayLevelNonUniformity [NUMERICAL]
# 	168 : RunEntropy [NUMERICAL]
# 	144 : GrayLevelVariance [NUMERICAL]
# 	135 : ShortRunHighGrayLevelEmphasis [NUMERICAL]
# 	131 : ShortRunLowGrayLevelEmphasis [NUMERICAL]
# 	120 : LongRunLowGrayLevelEmphasis [NUMERICAL]
# 	116 : RunVariance [NUMERICAL]
# 	96 : ShortRunEmphasis [NUMERICAL]
# 	92 : GrayLevelNonUniformityNormalized [NUMERICAL]
# 	85 : LongRunEmphasis [NUMERICAL]
# 	71 : HighGrayLevelRunEmphasis [NUMERICAL]
# 	60 : RunLengthNonUniformity [NUMERICAL]
# 	56 : LowGrayLevelRunEmphasis [NUMERICAL]
# 	40 : RunPercentage [NUMERICAL]
#
# Attribute in nodes with depth <= 3:
# 	520 : LongRunHighGrayLevelEmphasis [NUMERICAL]
# 	384 : GrayLevelVariance [NUMERICAL]
# 	357 : GrayLevelNonUniformity [NUMERICAL]
# 	346 : RunEntropy [NUMERICAL]
# 	334 : RunLengthNonUniformityNormalized [NUMERICAL]
# 	308 : ShortRunLowGrayLevelEmphasis [NUMERICAL]
# 	266 : ShortRunHighGrayLevelEmphasis [NUMERICAL]
# 	264 : LongRunLowGrayLevelEmphasis [NUMERICAL]
# 	221 : GrayLevelNonUniformityNormalized [NUMERICAL]
# 	211 : RunVariance [NUMERICAL]
# 	188 : ShortRunEmphasis [NUMERICAL]
# 	158 : HighGrayLevelRunEmphasis [NUMERICAL]
# 	155 : LongRunEmphasis [NUMERICAL]
# 	140 : LowGrayLevelRunEmphasis [NUMERICAL]
# 	119 : RunLengthNonUniformity [NUMERICAL]
# 	96 : RunPercentage [NUMERICAL]
#
# Attribute in nodes with depth <= 5:
# 	992 : LongRunHighGrayLevelEmphasis [NUMERICAL]
# 	763 : RunEntropy [NUMERICAL]
# 	745 : GrayLevelVariance [NUMERICAL]
# 	685 : GrayLevelNonUniformity [NUMERICAL]
# 	590 : ShortRunLowGrayLevelEmphasis [NUMERICAL]
# 	553 : ShortRunHighGrayLevelEmphasis [NUMERICAL]
# 	525 : RunLengthNonUniformityNormalized [NUMERICAL]
# 	525 : LongRunLowGrayLevelEmphasis [NUMERICAL]
# 	436 : RunVariance [NUMERICAL]
# 	374 : GrayLevelNonUniformityNormalized [NUMERICAL]
# 	349 : HighGrayLevelRunEmphasis [NUMERICAL]
# 	333 : ShortRunEmphasis [NUMERICAL]
# 	327 : LowGrayLevelRunEmphasis [NUMERICAL]
# 	299 : LongRunEmphasis [NUMERICAL]
# 	235 : RunPercentage [NUMERICAL]
# 	212 : RunLengthNonUniformity [NUMERICAL]
#
# Condition type in nodes:
# 	7943 : HigherCondition
# Condition type in nodes with depth <= 0:
# 	288 : HigherCondition
# Condition type in nodes with depth <= 1:
# 	864 : HigherCondition
# Condition type in nodes with depth <= 2:
# 	1967 : HigherCondition
# Condition type in nodes with depth <= 3:
# 	4067 : HigherCondition
# Condition type in nodes with depth <= 5:
# 	7943 : HigherCondition
#
# Training logs:
# Number of iteration to final model: 288
# 	Iter:1 train-loss:1.293374 valid-loss:1.293368  train-accuracy:0.814617 valid-accuracy:0.817327
# 	Iter:2 train-loss:1.217589 valid-loss:1.217684  train-accuracy:0.815629 valid-accuracy:0.818166
# 	Iter:3 train-loss:1.151612 valid-loss:1.151104  train-accuracy:0.825254 valid-accuracy:0.828283
# 	Iter:4 train-loss:1.094836 valid-loss:1.094821  train-accuracy:0.836031 valid-accuracy:0.837258
# 	Iter:5 train-loss:1.045857 valid-loss:1.046360  train-accuracy:0.835429 valid-accuracy:0.836118
# 	Iter:6 train-loss:1.005308 valid-loss:1.006509  train-accuracy:0.837252 valid-accuracy:0.838390
# 	Iter:16 train-loss:0.779317 valid-loss:0.788377  train-accuracy:0.849523 valid-accuracy:0.850731
# 	Iter:26 train-loss:0.697793 valid-loss:0.712104  train-accuracy:0.858360 valid-accuracy:0.854460
# 	Iter:36 train-loss:0.657496 valid-loss:0.676354  train-accuracy:0.864827 valid-accuracy:0.860029
# 	Iter:46 train-loss:0.630539 valid-loss:0.655369  train-accuracy:0.868544 valid-accuracy:0.863067
# 	Iter:56 train-loss:0.612280 valid-loss:0.642254  train-accuracy:0.871726 valid-accuracy:0.864196
# 	Iter:66 train-loss:0.597538 valid-loss:0.632558  train-accuracy:0.874419 valid-accuracy:0.863421
# 	Iter:76 train-loss:0.585366 valid-loss:0.624675  train-accuracy:0.876723 valid-accuracy:0.864258
# 	Iter:86 train-loss:0.575440 valid-loss:0.619368  train-accuracy:0.879247 valid-accuracy:0.867626
# 	Iter:96 train-loss:0.567669 valid-loss:0.615320  train-accuracy:0.881228 valid-accuracy:0.867772
# 	Iter:106 train-loss:0.559711 valid-loss:0.612119  train-accuracy:0.882804 valid-accuracy:0.868209
# 	Iter:116 train-loss:0.552828 valid-loss:0.609521  train-accuracy:0.884496 valid-accuracy:0.869895
# 	Iter:126 train-loss:0.547116 valid-loss:0.607747  train-accuracy:0.885519 valid-accuracy:0.869900
# 	Iter:136 train-loss:0.542093 valid-loss:0.605907  train-accuracy:0.887334 valid-accuracy:0.870740
# 	Iter:146 train-loss:0.536647 valid-loss:0.604516  train-accuracy:0.888312 valid-accuracy:0.872210
# 	Iter:156 train-loss:0.531668 valid-loss:0.603049  train-accuracy:0.889745 valid-accuracy:0.873781
# 	Iter:166 train-loss:0.527354 valid-loss:0.602816  train-accuracy:0.890943 valid-accuracy:0.873734
# 	Iter:176 train-loss:0.523169 valid-loss:0.602224  train-accuracy:0.891832 valid-accuracy:0.873655
# 	Iter:186 train-loss:0.519298 valid-loss:0.601338  train-accuracy:0.892855 valid-accuracy:0.874257
# 	Iter:196 train-loss:0.515614 valid-loss:0.600581  train-accuracy:0.894060 valid-accuracy:0.874977
# 	Iter:206 train-loss:0.512696 valid-loss:0.600007  train-accuracy:0.894687 valid-accuracy:0.873913
# 	Iter:216 train-loss:0.509094 valid-loss:0.599458  train-accuracy:0.895790 valid-accuracy:0.873784
# 	Iter:226 train-loss:0.505426 valid-loss:0.599186  train-accuracy:0.896581 valid-accuracy:0.873939
# 	Iter:236 train-loss:0.502103 valid-loss:0.598270  train-accuracy:0.897387 valid-accuracy:0.874888
# 	Iter:246 train-loss:0.498939 valid-loss:0.597717  train-accuracy:0.897901 valid-accuracy:0.874840
# 	Iter:256 train-loss:0.495735 valid-loss:0.597755  train-accuracy:0.898902 valid-accuracy:0.874230
# 	Iter:266 train-loss:0.492396 valid-loss:0.597536  train-accuracy:0.899757 valid-accuracy:0.873684
# 	Iter:276 train-loss:0.489100 valid-loss:0.596197  train-accuracy:0.900725 valid-accuracy:0.873740
# 	Iter:286 train-loss:0.485932 valid-loss:0.595262  train-accuracy:0.901870 valid-accuracy:0.874009
# 	Iter:296 train-loss:0.482971 valid-loss:0.595396  train-accuracy:0.902403 valid-accuracy:0.874062

# %%
# Model features
model.make_inspector().features()
# Out:
# ["GrayLevelNonUniformity" (1; #0),
#  "GrayLevelNonUniformityNormalized" (1; #1),
#  "GrayLevelVariance" (1; #2),
#  "HighGrayLevelRunEmphasis" (1; #3),
#  "LongRunEmphasis" (1; #4),
#  "LongRunHighGrayLevelEmphasis" (1; #5),
#  "LongRunLowGrayLevelEmphasis" (1; #6),
#  "LowGrayLevelRunEmphasis" (1; #7),
#  "RunEntropy" (1; #8),
#  "RunLengthNonUniformity" (1; #9),
#  "RunLengthNonUniformityNormalized" (1; #10),
#  "RunPercentage" (1; #11),
#  "RunVariance" (1; #12),
#  "ShortRunEmphasis" (1; #13),
#  "ShortRunHighGrayLevelEmphasis" (1; #14),
#  "ShortRunLowGrayLevelEmphasis" (1; #15)]

# %%
# Feature importance
model.make_inspector().variable_importances()
# Out:
# {'INV_MEAN_MIN_DEPTH': [("LongRunHighGrayLevelEmphasis" (1; #5),
#    0.23994896038895883),
#   ("RunLengthNonUniformityNormalized" (1; #10), 0.2314118104215785),
#   ("GrayLevelNonUniformity" (1; #0), 0.2183793679370018),
#   ("RunEntropy" (1; #8), 0.20587044459972376),
#   ("ShortRunLowGrayLevelEmphasis" (1; #15), 0.2025610379109641),
#   ("GrayLevelVariance" (1; #2), 0.1981725068563688),
#   ("ShortRunHighGrayLevelEmphasis" (1; #14), 0.19416252758624797),
#   ("ShortRunEmphasis" (1; #13), 0.19235998660829734),
#   ("LongRunLowGrayLevelEmphasis" (1; #6), 0.19232381278961758),
#   ("RunVariance" (1; #12), 0.18904861648494478),
#   ("HighGrayLevelRunEmphasis" (1; #3), 0.18455185740065697),
#   ("GrayLevelNonUniformityNormalized" (1; #1), 0.1842517912383333),
#   ("LowGrayLevelRunEmphasis" (1; #7), 0.18412623999219507),
#   ("RunLengthNonUniformity" (1; #9), 0.18361306782005032),
#   ("LongRunEmphasis" (1; #4), 0.1831347098754685),
#   ("RunPercentage" (1; #11), 0.1755410801177898)],
#  'NUM_AS_ROOT': [("RunLengthNonUniformityNormalized" (1; #10), 58.0),
#   ("LongRunHighGrayLevelEmphasis" (1; #5), 53.0),
#   ("GrayLevelNonUniformity" (1; #0), 44.0),
#   ("ShortRunLowGrayLevelEmphasis" (1; #15), 27.0),
#   ("ShortRunEmphasis" (1; #13), 20.0),
#   ("LongRunLowGrayLevelEmphasis" (1; #6), 17.0),
#   ("RunEntropy" (1; #8), 17.0),
#   ("LowGrayLevelRunEmphasis" (1; #7), 14.0),
#   ("RunLengthNonUniformity" (1; #9), 13.0),
#   ("HighGrayLevelRunEmphasis" (1; #3), 12.0),
#   ("GrayLevelVariance" (1; #2), 7.0),
#   ("ShortRunHighGrayLevelEmphasis" (1; #14), 3.0),
#   ("GrayLevelNonUniformityNormalized" (1; #1), 2.0),
#   ("RunVariance" (1; #12), 1.0)],
#  'SUM_SCORE': [("LowGrayLevelRunEmphasis" (1; #7), 51940.425282197975),
#   ("LongRunHighGrayLevelEmphasis" (1; #5), 46888.84937483675),
#   ("ShortRunLowGrayLevelEmphasis" (1; #15), 40670.51230369114),
#   ("ShortRunHighGrayLevelEmphasis" (1; #14), 32984.70625477903),
#   ("RunEntropy" (1; #8), 29194.262594513504),
#   ("GrayLevelNonUniformity" (1; #0), 14527.279565180817),
#   ("RunVariance" (1; #12), 11099.441008004635),
#   ("GrayLevelVariance" (1; #2), 7524.750292189554),
#   ("HighGrayLevelRunEmphasis" (1; #3), 7390.194390646623),
#   ("LongRunLowGrayLevelEmphasis" (1; #6), 5919.397248936205),
#   ("RunLengthNonUniformityNormalized" (1; #10), 5236.905868119525),
#   ("ShortRunEmphasis" (1; #13), 3649.111224079919),
#   ("RunPercentage" (1; #11), 1968.1703565444654),
#   ("RunLengthNonUniformity" (1; #9), 1913.644783122978),
#   ("LongRunEmphasis" (1; #4), 1763.2168833084663),
#   ("GrayLevelNonUniformityNormalized" (1; #1), 1742.1137489552184)],
#  'NUM_NODES': [("LongRunHighGrayLevelEmphasis" (1; #5), 992.0),
#   ("RunEntropy" (1; #8), 763.0),
#   ("GrayLevelVariance" (1; #2), 745.0),
#   ("GrayLevelNonUniformity" (1; #0), 685.0),
#   ("ShortRunLowGrayLevelEmphasis" (1; #15), 590.0),
#   ("ShortRunHighGrayLevelEmphasis" (1; #14), 553.0),
#   ("LongRunLowGrayLevelEmphasis" (1; #6), 525.0),
#   ("RunLengthNonUniformityNormalized" (1; #10), 525.0),
#   ("RunVariance" (1; #12), 436.0),
#   ("GrayLevelNonUniformityNormalized" (1; #1), 374.0),
#   ("HighGrayLevelRunEmphasis" (1; #3), 349.0),
#   ("ShortRunEmphasis" (1; #13), 333.0),
#   ("LowGrayLevelRunEmphasis" (1; #7), 327.0),
#   ("LongRunEmphasis" (1; #4), 299.0),
#   ("RunPercentage" (1; #11), 235.0),
#   ("RunLengthNonUniformity" (1; #9), 212.0)]}

# %%
# Model self evaluation
model.make_inspector().evaluation()
# Out:
# Evaluation(num_examples=None, accuracy=0.8736954927444458, loss=0.5951040387153625, rmse=None, ndcg=None, aucs=None, auuc=None, qini=None)

# %%
logs = model.make_inspector().training_logs()

plt.figure(figsize=(12, 4))
plt.subplot(1, 2, 1)
plt.plot([log.num_trees for log in logs], [log.evaluation.accuracy for log in logs])
plt.xlabel("Number of trees")
plt.ylabel("Accuracy (out-of-bag)")
plt.subplot(1, 2, 2)
plt.plot([log.num_trees for log in logs], [log.evaluation.loss for log in logs])
plt.xlabel("Number of trees")
plt.ylabel("Logloss (out-of-bag)")
plt.show()

# %% [markdown]
# Calculate the score of our hold-out validation dataset

# %%
predictions = model.predict(val_ds)
y_true      = validation_data["label"]

from sklearn.metrics import roc_auc_score
ROC_AUC = roc_auc_score(y_true, predictions)
print("The ROC AUC score is %.5f" % ROC_AUC )
# Out:
#  1/46 [..............................] - ETA: 2s
# 13/46 [=======>......................] - ETA: 0s
# 25/46 [===============>..............] - ETA: 0s
# 33/46 [====================>.........] - ETA: 0s
# 45/46 [============================>.] - ETA: 0s
# 46/46 [==============================] - 1s 19ms/step
# The ROC AUC score is 0.94822

# %%
# Compute binary classification metrics with sklearn
import numpy as np
from sklearn.metrics import (
    accuracy_score,
    precision_score,
    recall_score,
    f1_score,
    roc_auc_score,
    average_precision_score,
    confusion_matrix,
    classification_report,
    matthews_corrcoef,
    log_loss,
    brier_score_loss,
)

# Get predictions (probabilities or class labels)
preds = model.predict(test_ds)
# If model outputs probabilities, convert to labels by threshold 0.5
if preds.ndim == 2:
    # For TFDF classification, preds may be class probabilities with shape (N, 2)
    if preds.shape[1] == 2:
        pos_probs = preds[:, 1]
    else:
        # If single-probability column (positive class)
        pos_probs = preds[:, -1]
    y_pred = (pos_probs >= 0.5).astype(int)
else:
    # Already class labels
    y_pred = preds.astype(int)
    pos_probs = None

# Ground truth labels (must be 0/1 integers)
y_true = test_data["label"].astype(int).to_numpy()

# Core metrics
metrics = {}
metrics["accuracy"] = accuracy_score(y_true, y_pred)
metrics["precision"] = precision_score(y_true, y_pred, zero_division=0)
metrics["recall"] = recall_score(y_true, y_pred, zero_division=0)
metrics["f1"] = f1_score(y_true, y_pred, zero_division=0)
metrics["mcc"] = matthews_corrcoef(y_true, y_pred)

# Probabilistic metrics (only if we have probabilities)
if pos_probs is not None:
    metrics["roc_auc"] = roc_auc_score(y_true, pos_probs)
    metrics["pr_auc"] = average_precision_score(y_true, pos_probs)
    metrics["log_loss"] = log_loss(y_true, pos_probs, labels=[0,1])
    metrics["brier_score"] = brier_score_loss(y_true, pos_probs)

# Confusion matrix and detailed report
cm = confusion_matrix(y_true, y_pred, labels=[0,1])
report = classification_report(y_true, y_pred, digits=4)

print("Sklearn binary metrics:")
for k, v in metrics.items():
    print(f"{k}: {v:.4f}")
print("\nConfusion matrix:\n", cm)
print("\nClassification report:\n", report)
# Out:
#  1/91 [..............................] - ETA: 6s
# 13/91 [===>..........................] - ETA: 0s
# 20/91 [=====>........................] - ETA: 3s
# 33/91 [=========>....................] - ETA: 1s
# 44/91 [=============>................] - ETA: 1s
# 57/91 [=================>............] - ETA: 0s
# 70/91 [======================>.......] - ETA: 0s
# 83/91 [==========================>...] - ETA: 0s
# 91/91 [==============================] - 1s 14ms/step
# Sklearn binary metrics:
# accuracy: 0.8883
# precision: 0.3491
# recall: 0.8575
# f1: 0.4961
# mcc: 0.5029
# roc_auc: 0.9457
# pr_auc: 0.6790
# log_loss: 0.2682
# brier_score: 0.0819
#
# Confusion matrix:
#  [[75102  9246]
#  [  824  4958]]
#
# Classification report:
#                precision    recall  f1-score   support
#
#            0     0.9891    0.8904    0.9372     84348
#            1     0.3491    0.8575    0.4961      5782
#
#     accuracy                         0.8883     90130
#    macro avg     0.6691    0.8739    0.7167     90130
# weighted avg     0.9481    0.8883    0.9089     90130
