# %%
# Import packages and modules
import numpy  as np
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow_decision_forests as tfdf

from sklearn.model_selection import train_test_split
# Out:
# 2026-07-04 08:24:23.428630: I tensorflow/core/util/port.cc:113] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2026-07-04 08:24:23.472024: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2026-07-04 08:24:27.782102: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
# Check the version of TensorFlow Decision Forests
print("Found TensorFlow Decision Forests v" + tfdf.__version__)
# Out:
# Found TensorFlow Decision Forests v1.9.1

# %%
datasetPath = 'dataset/firstorder/kernel5-radius5/dataset.csv'

# %%
# Parameters
datasetPath = "dataset/glcm/kernel5-radius5/500.dataset.csv"

# %%
# train/validation/test = 70/10/20
dataset = pd.read_csv(datasetPath)

train_data, temp_data = train_test_split(dataset, test_size=0.3, random_state=42)
validation_data, test_data = train_test_split(temp_data, test_size=2/3, random_state=42)

# %%
from sklearn.utils.class_weight import compute_class_weight

# tinh class weight tren tap train
classes = np.array([0, 1])
weights = compute_class_weight(class_weight="balanced", classes=classes, y=train_data["label"])
class_weight = {0: weights[0], 1: weights[1]}

# gan sample_weight cho tung dong
train_data["sample_weight"] = train_data["label"].map(class_weight)
validation_data["sample_weight"] = validation_data["label"].map(class_weight)
test_data["sample_weight"] = test_data["label"].map(class_weight)

# Convert the dataset into a TensorFlow dataset.
train_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    train_data, label="label", weight="sample_weight"
)         
val_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    validation_data, label="label", weight="sample_weight"
)
test_ds = tfdf.keras.pd_dataframe_to_tf_dataset(
    test_data, label="label", weight="sample_weight"
)
# Out:
# 2026-07-04 08:24:41.105054: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:984] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2026-07-04 08:24:41.106759: W tensorflow/core/common_runtime/gpu/gpu_device.cc:2251] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...

# %%
import keras

# %%
# %%time

# Train a Gradient Boosted Trees model.
model = tfdf.keras.GradientBoostedTreesModel()

# Add evaluation metrics
model.compile(
    metrics=["accuracy"]
)
model.fit(x=train_ds)

# # Train a Gradient Boosted Trees model.
# model = tfdf.keras.GradientBoostedTreesModel(num_trees=1500)
# model.fit(train_ds)
# Out:
# Use /tmp/tmp4vgam45k as temporary training directory
# Reading training dataset...
# [WARNING 26-07-04 08:24:41.3386 UTC gradient_boosted_trees.cc:1840] "goss_alpha" set but "sampling_method" not equal to "GOSS".
# [WARNING 26-07-04 08:24:41.3387 UTC gradient_boosted_trees.cc:1851] "goss_beta" set but "sampling_method" not equal to "GOSS".
# [WARNING 26-07-04 08:24:41.3387 UTC gradient_boosted_trees.cc:1865] "selective_gradient_boosting_ratio" set but "sampling_method" not equal to "SELGB".
# Training dataset read in 0:00:04.776931. Found 395895 examples.
# Training model...
# Model trained in 0:02:06.053199
# Compiling model...
# [INFO 26-07-04 08:26:52.1746 UTC kernel.cc:1233] Loading model from path /tmp/tmp4vgam45k/model/ with prefix e8b76710edbb4e35
# [INFO 26-07-04 08:26:52.1908 UTC quick_scorer_extended.cc:911] The binary was compiled without AVX2 support, but your CPU supports it. Enable it for faster model inference.
# [INFO 26-07-04 08:26:52.1920 UTC abstract_model.cc:1362] Engine "GradientBoostedTreesQuickScorerExtended" built
# [INFO 26-07-04 08:26:52.1920 UTC kernel.cc:1061] Use fast generic engine
# Model compiled.
# CPU times: user 20min 45s, sys: 6.78 s, total: 20min 51s
# Wall time: 2min 13s

# %%
# Evaluate the model
evaluate = model.evaluate(val_ds, return_dict=True)
print()

for name, value in evaluate.items():
    print(f"{name}: {value:.4f}")
# Out:
# WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
#  1/57 [..............................] - ETA: 4:12 - loss: 0.0000e+00 - accuracy: 0.9340
#  9/57 [===>..........................] - ETA: 0s - loss: 0.0000e+00 - accuracy: 0.9234
# 18/57 [========>.....................] - ETA: 0s - loss: 0.0000e+00 - accuracy: 0.9234
# 25/57 [============>.................] - ETA: 0s - loss: 0.0000e+00 - accuracy: 0.9229
# 32/57 [===============>..............] - ETA: 0s - loss: 0.0000e+00 - accuracy: 0.9233
# 41/57 [====================>.........] - ETA: 0s - loss: 0.0000e+00 - accuracy: 0.9238
# 50/57 [=========================>....] - ETA: 0s - loss: 0.0000e+00 - accuracy: 0.9238
# 57/57 [==============================] - 5s 6ms/step - loss: 0.0000e+00 - accuracy: 0.9234
# loss: 0.0000
# accuracy: 0.9234

# %%
# Model Summary
model.summary()
# Out:
# Model: "gradient_boosted_trees_model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
# =================================================================
# Total params: 1 (1.00 Byte)
# Trainable params: 0 (0.00 Byte)
# Non-trainable params: 1 (1.00 Byte)
# _________________________________________________________________
# Type: "GRADIENT_BOOSTED_TREES"
# Task: CLASSIFICATION
# Label: "__LABEL"
#
# Input Features (24):
# 	Autocorrelation
# 	ClusterProminence
# 	ClusterShade
# 	ClusterTendency
# 	Contrast
# 	Correlation
# 	DifferenceAverage
# 	DifferenceEntropy
# 	DifferenceVariance
# 	Id
# 	Idm
# 	Idmn
# 	Idn
# 	Imc1
# 	Imc2
# 	InverseVariance
# 	JointAverage
# 	JointEnergy
# 	JointEntropy
# 	MCC
# 	MaximumProbability
# 	SumAverage
# 	SumEntropy
# 	SumSquares
#
# Trained with weights
#
# Variable Importance: INV_MEAN_MIN_DEPTH:
#     1.                "Idn"  0.253554 ################
#     2.               "Idmn"  0.229032 ###########
#     3.       "ClusterShade"  0.200064 #####
#     4.        "Correlation"  0.198205 #####
#     5.    "Autocorrelation"  0.197968 #####
#     6.       "JointAverage"  0.197230 #####
#     7.               "Imc1"  0.196581 ####
#     8.         "SumAverage"  0.193824 ####
#     9. "DifferenceVariance"  0.189393 ###
#    10.    "InverseVariance"  0.188882 ###
#    11.  "DifferenceAverage"  0.186123 ##
#    12.  "DifferenceEntropy"  0.183191 ##
#    13.           "Contrast"  0.181727 #
#    14. "MaximumProbability"  0.180432 #
#    15.               "Imc2"  0.177553 #
#    16.         "SumEntropy"  0.177087 #
#    17.                 "Id"  0.175675
#    18.                "MCC"  0.175448
#    19.         "SumSquares"  0.174586
#    20.  "ClusterProminence"  0.174115
#    21.                "Idm"  0.173901
#    22.    "ClusterTendency"  0.173497
#    23.       "JointEntropy"  0.171769
#    24.        "JointEnergy"  0.171497
#
# Variable Importance: NUM_AS_ROOT:
#     1.                "Idn" 96.000000 ################
#     2.               "Idmn" 67.000000 ###########
#     3.        "Correlation" 30.000000 ####
#     4.               "Imc1" 30.000000 ####
#     5.    "Autocorrelation" 19.000000 ###
#     6.         "SumAverage" 18.000000 ##
#     7.       "JointAverage" 15.000000 ##
#     8.  "DifferenceAverage"  6.000000
#     9.               "Imc2"  5.000000
#    10.           "Contrast"  4.000000
#    11.    "InverseVariance"  4.000000
#    12.       "ClusterShade"  3.000000
#    13.  "DifferenceEntropy"  1.000000
#    14. "DifferenceVariance"  1.000000
#
# Variable Importance: NUM_NODES:
#     1.       "ClusterShade" 759.000000 ################
#     2.    "Autocorrelation" 718.000000 ##############
#     3.               "Idmn" 629.000000 ############
#     4.                "Idn" 598.000000 ############
#     5.       "JointAverage" 523.000000 ##########
#     6.         "SumAverage" 483.000000 #########
#     7.        "Correlation" 445.000000 ########
#     8.    "InverseVariance" 440.000000 ########
#     9. "DifferenceVariance" 418.000000 #######
#    10.               "Imc1" 366.000000 ######
#    11.  "DifferenceEntropy" 334.000000 #####
#    12. "MaximumProbability" 302.000000 ####
#    13.  "DifferenceAverage" 260.000000 ###
#    14.         "SumEntropy" 254.000000 ###
#    15.               "Imc2" 252.000000 ###
#    16.                "MCC" 252.000000 ###
#    17.  "ClusterProminence" 227.000000 ##
#    18.           "Contrast" 207.000000 ##
#    19.                 "Id" 155.000000 #
#    20.         "SumSquares" 153.000000 #
#    21.    "ClusterTendency" 140.000000
#    22.                "Idm" 134.000000
#    23.        "JointEnergy" 130.000000
#    24.       "JointEntropy" 109.000000
#
# Variable Importance: SUM_SCORE:
#     1.        "Correlation" 92345.318842 ################
#     2.       "JointAverage" 56005.803791 #########
#     3. "DifferenceVariance" 42857.467585 #######
#     4.         "SumAverage" 42038.678909 #######
#     5.    "Autocorrelation" 23191.160547 ###
#     6.                "Idn" 18599.157909 ###
#     7. "MaximumProbability" 16803.179974 ##
#     8.    "InverseVariance" 15828.688715 ##
#     9.               "Idmn" 13311.257061 ##
#    10.       "ClusterShade" 11666.192788 #
#    11.               "Imc1" 10719.362411 #
#    12.  "DifferenceEntropy" 5515.980374
#    13.           "Contrast" 4863.184915
#    14.                 "Id" 2740.110932
#    15.         "SumEntropy" 2610.449283
#    16.  "DifferenceAverage" 2206.070040
#    17.               "Imc2" 1461.983377
#    18.                "Idm" 1333.495706
#    19.  "ClusterProminence" 1158.936823
#    20.        "JointEnergy" 987.078525
#    21.                "MCC" 950.678803
#    22.         "SumSquares" 898.279660
#    23.    "ClusterTendency" 695.877342
#    24.       "JointEntropy" 465.555087
#
#
#
# Loss: BINOMIAL_LOG_LIKELIHOOD
# Validation loss value: 0.429181
# Number of trees per iteration: 1
# Node format: NOT_SET
# Number of trees: 299
# Total number of nodes: 16875
#
# Number of nodes by tree:
# Count: 299 Average: 56.4381 StdDev: 7.48367
# Min: 31 Max: 63 Ignored: 0
# ----------------------------------------------
# [ 31, 32)   2   0.67%   0.67%
# [ 32, 34)   1   0.33%   1.00%
# [ 34, 35)   0   0.00%   1.00%
# [ 35, 37)   3   1.00%   2.01%
# [ 37, 39)   2   0.67%   2.68%
# [ 39, 40)   1   0.33%   3.01%
# [ 40, 42)   6   2.01%   5.02% #
# [ 42, 44)  10   3.34%   8.36% #
# [ 44, 45)   0   0.00%   8.36%
# [ 45, 47)   7   2.34%  10.70% #
# [ 47, 49)  14   4.68%  15.38% #
# [ 49, 50)  18   6.02%  21.40% ##
# [ 50, 52)  15   5.02%  26.42% #
# [ 52, 54)  17   5.69%  32.11% ##
# [ 54, 55)   0   0.00%  32.11%
# [ 55, 57)  14   4.68%  36.79% #
# [ 57, 59)  23   7.69%  44.48% ##
# [ 59, 60)  22   7.36%  51.84% ##
# [ 60, 62)  43  14.38%  66.22% ####
# [ 62, 63] 101  33.78% 100.00% ##########
#
# Depth by leafs:
# Count: 8587 Average: 4.91965 StdDev: 0.363169
# Min: 2 Max: 5 Ignored: 0
# ----------------------------------------------
# [ 2, 3)   42   0.49%   0.49%
# [ 3, 4)  123   1.43%   1.92%
# [ 4, 5)  318   3.70%   5.62%
# [ 5, 5] 8104  94.38% 100.00% ##########
#
# Number of training obs by leaf:
# Count: 8587 Average: 12402.7 StdDev: 37247
# Min: 5 Max: 351215 Ignored: 0
# ----------------------------------------------
# [      5,  17565) 7316  85.20%  85.20% ##########
# [  17565,  35126)  532   6.20%  91.39% #
# [  35126,  52686)  235   2.74%  94.13%
# [  52686,  70247)  129   1.50%  95.63%
# [  70247,  87807)   89   1.04%  96.67%
# [  87807, 105368)   55   0.64%  97.31%
# [ 105368, 122928)   27   0.31%  97.62%
# [ 122928, 140489)   29   0.34%  97.96%
# [ 140489, 158049)   31   0.36%  98.32%
# [ 158049, 175610)   16   0.19%  98.51%
# [ 175610, 193171)   10   0.12%  98.63%
# [ 193171, 210731)   11   0.13%  98.75%
# [ 210731, 228292)   15   0.17%  98.93%
# [ 228292, 245852)   21   0.24%  99.17%
# [ 245852, 263413)   18   0.21%  99.38%
# [ 263413, 280973)   12   0.14%  99.52%
# [ 280973, 298534)   15   0.17%  99.70%
# [ 298534, 316094)    4   0.05%  99.74%
# [ 316094, 333655)   14   0.16%  99.91%
# [ 333655, 351215]    8   0.09% 100.00%
#
# Attribute in nodes:
# 	759 : ClusterShade [NUMERICAL]
# 	718 : Autocorrelation [NUMERICAL]
# 	629 : Idmn [NUMERICAL]
# 	598 : Idn [NUMERICAL]
# 	523 : JointAverage [NUMERICAL]
# 	483 : SumAverage [NUMERICAL]
# 	445 : Correlation [NUMERICAL]
# 	440 : InverseVariance [NUMERICAL]
# 	418 : DifferenceVariance [NUMERICAL]
# 	366 : Imc1 [NUMERICAL]
# 	334 : DifferenceEntropy [NUMERICAL]
# 	302 : MaximumProbability [NUMERICAL]
# 	260 : DifferenceAverage [NUMERICAL]
# 	254 : SumEntropy [NUMERICAL]
# 	252 : MCC [NUMERICAL]
# 	252 : Imc2 [NUMERICAL]
# 	227 : ClusterProminence [NUMERICAL]
# 	207 : Contrast [NUMERICAL]
# 	155 : Id [NUMERICAL]
# 	153 : SumSquares [NUMERICAL]
# 	140 : ClusterTendency [NUMERICAL]
# 	134 : Idm [NUMERICAL]
# 	130 : JointEnergy [NUMERICAL]
# 	109 : JointEntropy [NUMERICAL]
#
# Attribute in nodes with depth <= 0:
# 	96 : Idn [NUMERICAL]
# 	67 : Idmn [NUMERICAL]
# 	30 : Imc1 [NUMERICAL]
# 	30 : Correlation [NUMERICAL]
# 	19 : Autocorrelation [NUMERICAL]
# 	18 : SumAverage [NUMERICAL]
# 	15 : JointAverage [NUMERICAL]
# 	6 : DifferenceAverage [NUMERICAL]
# 	5 : Imc2 [NUMERICAL]
# 	4 : InverseVariance [NUMERICAL]
# 	4 : Contrast [NUMERICAL]
# 	3 : ClusterShade [NUMERICAL]
# 	1 : DifferenceVariance [NUMERICAL]
# 	1 : DifferenceEntropy [NUMERICAL]
#
# Attribute in nodes with depth <= 1:
# 	147 : Idn [NUMERICAL]
# 	113 : Idmn [NUMERICAL]
# 	73 : ClusterShade [NUMERICAL]
# 	61 : Correlation [NUMERICAL]
# 	56 : DifferenceVariance [NUMERICAL]
# 	53 : JointAverage [NUMERICAL]
# 	47 : Imc1 [NUMERICAL]
# 	47 : DifferenceAverage [NUMERICAL]
# 	43 : InverseVariance [NUMERICAL]
# 	39 : DifferenceEntropy [NUMERICAL]
# 	36 : Autocorrelation [NUMERICAL]
# 	35 : SumAverage [NUMERICAL]
# 	35 : Contrast [NUMERICAL]
# 	26 : MaximumProbability [NUMERICAL]
# 	19 : Id [NUMERICAL]
# 	14 : Imc2 [NUMERICAL]
# 	13 : SumSquares [NUMERICAL]
# 	11 : MCC [NUMERICAL]
# 	9 : Idm [NUMERICAL]
# 	8 : SumEntropy [NUMERICAL]
# 	7 : ClusterTendency [NUMERICAL]
# 	3 : JointEntropy [NUMERICAL]
# 	2 : ClusterProminence [NUMERICAL]
#
# Attribute in nodes with depth <= 2:
# 	206 : Idn [NUMERICAL]
# 	180 : Idmn [NUMERICAL]
# 	174 : ClusterShade [NUMERICAL]
# 	155 : Autocorrelation [NUMERICAL]
# 	147 : JointAverage [NUMERICAL]
# 	117 : SumAverage [NUMERICAL]
# 	114 : InverseVariance [NUMERICAL]
# 	113 : Correlation [NUMERICAL]
# 	111 : DifferenceVariance [NUMERICAL]
# 	105 : Imc1 [NUMERICAL]
# 	101 : DifferenceAverage [NUMERICAL]
# 	76 : MaximumProbability [NUMERICAL]
# 	76 : DifferenceEntropy [NUMERICAL]
# 	70 : Contrast [NUMERICAL]
# 	53 : SumEntropy [NUMERICAL]
# 	46 : Imc2 [NUMERICAL]
# 	35 : Id [NUMERICAL]
# 	32 : MCC [NUMERICAL]
# 	30 : SumSquares [NUMERICAL]
# 	30 : Idm [NUMERICAL]
# 	29 : ClusterTendency [NUMERICAL]
# 	29 : ClusterProminence [NUMERICAL]
# 	14 : JointEntropy [NUMERICAL]
# 	8 : JointEnergy [NUMERICAL]
#
# Attribute in nodes with depth <= 3:
# 	366 : ClusterShade [NUMERICAL]
# 	350 : Autocorrelation [NUMERICAL]
# 	336 : Idn [NUMERICAL]
# 	327 : Idmn [NUMERICAL]
# 	301 : JointAverage [NUMERICAL]
# 	253 : SumAverage [NUMERICAL]
# 	236 : InverseVariance [NUMERICAL]
# 	219 : Correlation [NUMERICAL]
# 	212 : DifferenceVariance [NUMERICAL]
# 	201 : Imc1 [NUMERICAL]
# 	177 : DifferenceEntropy [NUMERICAL]
# 	163 : DifferenceAverage [NUMERICAL]
# 	144 : MaximumProbability [NUMERICAL]
# 	138 : SumEntropy [NUMERICAL]
# 	128 : Contrast [NUMERICAL]
# 	107 : Imc2 [NUMERICAL]
# 	105 : MCC [NUMERICAL]
# 	104 : ClusterProminence [NUMERICAL]
# 	80 : Id [NUMERICAL]
# 	68 : SumSquares [NUMERICAL]
# 	68 : Idm [NUMERICAL]
# 	57 : ClusterTendency [NUMERICAL]
# 	50 : JointEnergy [NUMERICAL]
# 	46 : JointEntropy [NUMERICAL]
#
# Attribute in nodes with depth <= 5:
# 	759 : ClusterShade [NUMERICAL]
# 	718 : Autocorrelation [NUMERICAL]
# 	629 : Idmn [NUMERICAL]
# 	598 : Idn [NUMERICAL]
# 	523 : JointAverage [NUMERICAL]
# 	483 : SumAverage [NUMERICAL]
# 	445 : Correlation [NUMERICAL]
# 	440 : InverseVariance [NUMERICAL]
# 	418 : DifferenceVariance [NUMERICAL]
# 	366 : Imc1 [NUMERICAL]
# 	334 : DifferenceEntropy [NUMERICAL]
# 	302 : MaximumProbability [NUMERICAL]
# 	260 : DifferenceAverage [NUMERICAL]
# 	254 : SumEntropy [NUMERICAL]
# 	252 : MCC [NUMERICAL]
# 	252 : Imc2 [NUMERICAL]
# 	227 : ClusterProminence [NUMERICAL]
# 	207 : Contrast [NUMERICAL]
# 	155 : Id [NUMERICAL]
# 	153 : SumSquares [NUMERICAL]
# 	140 : ClusterTendency [NUMERICAL]
# 	134 : Idm [NUMERICAL]
# 	130 : JointEnergy [NUMERICAL]
# 	109 : JointEntropy [NUMERICAL]
#
# Condition type in nodes:
# 	8288 : HigherCondition
# Condition type in nodes with depth <= 0:
# 	299 : HigherCondition
# Condition type in nodes with depth <= 1:
# 	897 : HigherCondition
# Condition type in nodes with depth <= 2:
# 	2051 : HigherCondition
# Condition type in nodes with depth <= 3:
# 	4236 : HigherCondition
# Condition type in nodes with depth <= 5:
# 	8288 : HigherCondition
#
# Training logs:
# Number of iteration to final model: 299
# 	Iter:1 train-loss:1.291607 valid-loss:1.292767  train-accuracy:0.820818 valid-accuracy:0.816852
# 	Iter:2 train-loss:1.216073 valid-loss:1.218027  train-accuracy:0.826808 valid-accuracy:0.824111
# 	Iter:3 train-loss:1.152012 valid-loss:1.154660  train-accuracy:0.834517 valid-accuracy:0.831643
# 	Iter:4 train-loss:1.093346 valid-loss:1.097652  train-accuracy:0.837216 valid-accuracy:0.831018
# 	Iter:5 train-loss:1.044038 valid-loss:1.049485  train-accuracy:0.842441 valid-accuracy:0.834825
# 	Iter:6 train-loss:1.002554 valid-loss:1.008624  train-accuracy:0.843351 valid-accuracy:0.837427
# 	Iter:16 train-loss:0.747527 valid-loss:0.759565  train-accuracy:0.869232 valid-accuracy:0.865240
# 	Iter:26 train-loss:0.627491 valid-loss:0.645357  train-accuracy:0.884425 valid-accuracy:0.878238
# 	Iter:36 train-loss:0.554182 valid-loss:0.577932  train-accuracy:0.896362 valid-accuracy:0.890252
# 	Iter:46 train-loss:0.512942 valid-loss:0.541764  train-accuracy:0.903708 valid-accuracy:0.897361
# 	Iter:56 train-loss:0.485205 valid-loss:0.516558  train-accuracy:0.908525 valid-accuracy:0.902004
# 	Iter:66 train-loss:0.462530 valid-loss:0.496775  train-accuracy:0.912177 valid-accuracy:0.903549
# 	Iter:76 train-loss:0.446185 valid-loss:0.483606  train-accuracy:0.915495 valid-accuracy:0.907313
# 	Iter:86 train-loss:0.433002 valid-loss:0.473229  train-accuracy:0.917468 valid-accuracy:0.907970
# 	Iter:96 train-loss:0.422390 valid-loss:0.464534  train-accuracy:0.919359 valid-accuracy:0.910307
# 	Iter:106 train-loss:0.413448 valid-loss:0.458689  train-accuracy:0.920982 valid-accuracy:0.911757
# 	Iter:116 train-loss:0.406038 valid-loss:0.454417  train-accuracy:0.921729 valid-accuracy:0.912418
# 	Iter:126 train-loss:0.400903 valid-loss:0.451706  train-accuracy:0.922728 valid-accuracy:0.912973
# 	Iter:136 train-loss:0.394521 valid-loss:0.448245  train-accuracy:0.923463 valid-accuracy:0.913846
# 	Iter:146 train-loss:0.389022 valid-loss:0.445465  train-accuracy:0.924420 valid-accuracy:0.914086
# 	Iter:156 train-loss:0.384126 valid-loss:0.443002  train-accuracy:0.925257 valid-accuracy:0.914162
# 	Iter:166 train-loss:0.379897 valid-loss:0.441031  train-accuracy:0.926012 valid-accuracy:0.914583
# 	Iter:176 train-loss:0.376884 valid-loss:0.439652  train-accuracy:0.926369 valid-accuracy:0.915133
# 	Iter:186 train-loss:0.372751 valid-loss:0.438058  train-accuracy:0.927138 valid-accuracy:0.914942
# 	Iter:196 train-loss:0.369343 valid-loss:0.436554  train-accuracy:0.927946 valid-accuracy:0.915381
# 	Iter:206 train-loss:0.366063 valid-loss:0.435426  train-accuracy:0.928631 valid-accuracy:0.914983
# 	Iter:216 train-loss:0.362894 valid-loss:0.434567  train-accuracy:0.929119 valid-accuracy:0.915236
# 	Iter:226 train-loss:0.359992 valid-loss:0.433589  train-accuracy:0.929635 valid-accuracy:0.915998
# 	Iter:236 train-loss:0.357046 valid-loss:0.432691  train-accuracy:0.930641 valid-accuracy:0.915968
# 	Iter:246 train-loss:0.353741 valid-loss:0.431734  train-accuracy:0.931330 valid-accuracy:0.915946
# 	Iter:256 train-loss:0.350817 valid-loss:0.431106  train-accuracy:0.931892 valid-accuracy:0.915587
# 	Iter:266 train-loss:0.348660 valid-loss:0.431118  train-accuracy:0.932181 valid-accuracy:0.914966
# 	Iter:276 train-loss:0.346586 valid-loss:0.430699  train-accuracy:0.932600 valid-accuracy:0.915529
# 	Iter:286 train-loss:0.344209 valid-loss:0.430209  train-accuracy:0.933274 valid-accuracy:0.915924
# 	Iter:296 train-loss:0.341657 valid-loss:0.429402  train-accuracy:0.933806 valid-accuracy:0.915698

# %%
# Model features
model.make_inspector().features()
# Out:
# ["Autocorrelation" (1; #0),
#  "ClusterProminence" (1; #1),
#  "ClusterShade" (1; #2),
#  "ClusterTendency" (1; #3),
#  "Contrast" (1; #4),
#  "Correlation" (1; #5),
#  "DifferenceAverage" (1; #6),
#  "DifferenceEntropy" (1; #7),
#  "DifferenceVariance" (1; #8),
#  "Id" (1; #9),
#  "Idm" (1; #10),
#  "Idmn" (1; #11),
#  "Idn" (1; #12),
#  "Imc1" (1; #13),
#  "Imc2" (1; #14),
#  "InverseVariance" (1; #15),
#  "JointAverage" (1; #16),
#  "JointEnergy" (1; #17),
#  "JointEntropy" (1; #18),
#  "MCC" (1; #19),
#  "MaximumProbability" (1; #20),
#  "SumAverage" (1; #21),
#  "SumEntropy" (1; #22),
#  "SumSquares" (1; #23)]

# %%
# Feature importance
model.make_inspector().variable_importances()
# Out:
# {'INV_MEAN_MIN_DEPTH': [("Idn" (1; #12), 0.25355434420081485),
#   ("Idmn" (1; #11), 0.22903220891564915),
#   ("ClusterShade" (1; #2), 0.20006447519274892),
#   ("Correlation" (1; #5), 0.19820461008187512),
#   ("Autocorrelation" (1; #0), 0.19796833516124784),
#   ("JointAverage" (1; #16), 0.1972302485469614),
#   ("Imc1" (1; #13), 0.19658079895316144),
#   ("SumAverage" (1; #21), 0.19382352123028807),
#   ("DifferenceVariance" (1; #8), 0.18939268692433006),
#   ("InverseVariance" (1; #15), 0.18888243924652215),
#   ("DifferenceAverage" (1; #6), 0.1861234887460956),
#   ("DifferenceEntropy" (1; #7), 0.18319056778296536),
#   ("Contrast" (1; #4), 0.18172686817320954),
#   ("MaximumProbability" (1; #20), 0.18043176999272062),
#   ("Imc2" (1; #14), 0.17755347925181078),
#   ("SumEntropy" (1; #22), 0.1770867542110796),
#   ("Id" (1; #9), 0.17567484931274646),
#   ("MCC" (1; #19), 0.17544799776873057),
#   ("SumSquares" (1; #23), 0.1745860582410002),
#   ("ClusterProminence" (1; #1), 0.17411452760023977),
#   ("Idm" (1; #10), 0.17390070087268186),
#   ("ClusterTendency" (1; #3), 0.1734970514839746),
#   ("JointEntropy" (1; #18), 0.17176902952651008),
#   ("JointEnergy" (1; #17), 0.17149701416210478)],
#  'SUM_SCORE': [("Correlation" (1; #5), 92345.3188421081),
#   ("JointAverage" (1; #16), 56005.80379056165),
#   ("DifferenceVariance" (1; #8), 42857.46758549263),
#   ("SumAverage" (1; #21), 42038.67890851817),
#   ("Autocorrelation" (1; #0), 23191.160546903888),
#   ("Idn" (1; #12), 18599.157909173122),
#   ("MaximumProbability" (1; #20), 16803.17997449113),
#   ("InverseVariance" (1; #15), 15828.68871491738),
#   ("Idmn" (1; #11), 13311.257060614871),
#   ("ClusterShade" (1; #2), 11666.192788461207),
#   ("Imc1" (1; #13), 10719.362411426917),
#   ("DifferenceEntropy" (1; #7), 5515.980373668114),
#   ("Contrast" (1; #4), 4863.18491468833),
#   ("Id" (1; #9), 2740.1109316296174),
#   ("SumEntropy" (1; #22), 2610.449282844748),
#   ("DifferenceAverage" (1; #6), 2206.0700397323553),
#   ("Imc2" (1; #14), 1461.983377303634),
#   ("Idm" (1; #10), 1333.495706406357),
#   ("ClusterProminence" (1; #1), 1158.93682344792),
#   ("JointEnergy" (1; #17), 987.0785245625814),
#   ("MCC" (1; #19), 950.6788029186769),
#   ("SumSquares" (1; #23), 898.2796595190166),
#   ("ClusterTendency" (1; #3), 695.8773424685305),
#   ("JointEntropy" (1; #18), 465.555087152429)],
#  'NUM_AS_ROOT': [("Idn" (1; #12), 96.0),
#   ("Idmn" (1; #11), 67.0),
#   ("Correlation" (1; #5), 30.0),
#   ("Imc1" (1; #13), 30.0),
#   ("Autocorrelation" (1; #0), 19.0),
#   ("SumAverage" (1; #21), 18.0),
#   ("JointAverage" (1; #16), 15.0),
#   ("DifferenceAverage" (1; #6), 6.0),
#   ("Imc2" (1; #14), 5.0),
#   ("Contrast" (1; #4), 4.0),
#   ("InverseVariance" (1; #15), 4.0),
#   ("ClusterShade" (1; #2), 3.0),
#   ("DifferenceEntropy" (1; #7), 1.0),
#   ("DifferenceVariance" (1; #8), 1.0)],
#  'NUM_NODES': [("ClusterShade" (1; #2), 759.0),
#   ("Autocorrelation" (1; #0), 718.0),
#   ("Idmn" (1; #11), 629.0),
#   ("Idn" (1; #12), 598.0),
#   ("JointAverage" (1; #16), 523.0),
#   ("SumAverage" (1; #21), 483.0),
#   ("Correlation" (1; #5), 445.0),
#   ("InverseVariance" (1; #15), 440.0),
#   ("DifferenceVariance" (1; #8), 418.0),
#   ("Imc1" (1; #13), 366.0),
#   ("DifferenceEntropy" (1; #7), 334.0),
#   ("MaximumProbability" (1; #20), 302.0),
#   ("DifferenceAverage" (1; #6), 260.0),
#   ("SumEntropy" (1; #22), 254.0),
#   ("Imc2" (1; #14), 252.0),
#   ("MCC" (1; #19), 252.0),
#   ("ClusterProminence" (1; #1), 227.0),
#   ("Contrast" (1; #4), 207.0),
#   ("Id" (1; #9), 155.0),
#   ("SumSquares" (1; #23), 153.0),
#   ("ClusterTendency" (1; #3), 140.0),
#   ("Idm" (1; #10), 134.0),
#   ("JointEnergy" (1; #17), 130.0),
#   ("JointEntropy" (1; #18), 109.0)]}

# %%
# Model self evaluation
model.make_inspector().evaluation()
# Out:
# Evaluation(num_examples=None, accuracy=0.9153081178665161, loss=0.4291808605194092, rmse=None, ndcg=None, aucs=None, auuc=None, qini=None)

# %%
logs = model.make_inspector().training_logs()

plt.figure(figsize=(12, 4))
plt.subplot(1, 2, 1)
plt.plot([log.num_trees for log in logs], [log.evaluation.accuracy for log in logs])
plt.xlabel("Number of trees")
plt.ylabel("Accuracy (out-of-bag)")
plt.subplot(1, 2, 2)
plt.plot([log.num_trees for log in logs], [log.evaluation.loss for log in logs])
plt.xlabel("Number of trees")
plt.ylabel("Logloss (out-of-bag)")
plt.show()

# %% [markdown]
# Calculate the score of our hold-out validation dataset

# %%
predictions = model.predict(val_ds)
y_true      = validation_data["label"]

from sklearn.metrics import roc_auc_score
ROC_AUC = roc_auc_score(y_true, predictions)
print("The ROC AUC score is %.5f" % ROC_AUC )
# Out:
#  1/57 [..............................] - ETA: 3s
#  9/57 [===>..........................] - ETA: 0s
# 18/57 [========>.....................] - ETA: 0s
# 26/57 [============>.................] - ETA: 0s
# 35/57 [=================>............] - ETA: 0s
# 45/57 [======================>.......] - ETA: 0s
# 54/57 [===========================>..] - ETA: 0s
# 57/57 [==============================] - 0s 6ms/step
# The ROC AUC score is 0.97303

# %%
# Compute binary classification metrics with sklearn
import numpy as np
from sklearn.metrics import (
    accuracy_score,
    precision_score,
    recall_score,
    f1_score,
    roc_auc_score,
    average_precision_score,
    confusion_matrix,
    classification_report,
    matthews_corrcoef,
    log_loss,
    brier_score_loss,
)

# Get predictions (probabilities or class labels)
preds = model.predict(test_ds)
# If model outputs probabilities, convert to labels by threshold 0.5
if preds.ndim == 2:
    # For TFDF classification, preds may be class probabilities with shape (N, 2)
    if preds.shape[1] == 2:
        pos_probs = preds[:, 1]
    else:
        # If single-probability column (positive class)
        pos_probs = preds[:, -1]
    y_pred = (pos_probs >= 0.5).astype(int)
else:
    # Already class labels
    y_pred = preds.astype(int)
    pos_probs = None

# Ground truth labels (must be 0/1 integers)
y_true = test_data["label"].astype(int).to_numpy()

# Core metrics
metrics = {}
metrics["accuracy"] = accuracy_score(y_true, y_pred)
metrics["precision"] = precision_score(y_true, y_pred, zero_division=0)
metrics["recall"] = recall_score(y_true, y_pred, zero_division=0)
metrics["f1"] = f1_score(y_true, y_pred, zero_division=0)
metrics["mcc"] = matthews_corrcoef(y_true, y_pred)

# Probabilistic metrics (only if we have probabilities)
if pos_probs is not None:
    metrics["roc_auc"] = roc_auc_score(y_true, pos_probs)
    metrics["pr_auc"] = average_precision_score(y_true, pos_probs)
    metrics["log_loss"] = log_loss(y_true, pos_probs, labels=[0,1])
    metrics["brier_score"] = brier_score_loss(y_true, pos_probs)

# Confusion matrix and detailed report
cm = confusion_matrix(y_true, y_pred, labels=[0,1])
report = classification_report(y_true, y_pred, digits=4)

print("Sklearn binary metrics:")
for k, v in metrics.items():
    print(f"{k}: {v:.4f}")
print("\nConfusion matrix:\n", cm)
print("\nClassification report:\n", report)
# Out:
#   1/114 [..............................] - ETA: 8s
#  10/114 [=>............................] - ETA: 0s
#  19/114 [====>.........................] - ETA: 0s
#  28/114 [======>.......................] - ETA: 0s
#  37/114 [========>.....................] - ETA: 0s
#  46/114 [===========>..................] - ETA: 0s
#  56/114 [=============>................] - ETA: 0s
#  65/114 [================>.............] - ETA: 0s
#  74/114 [==================>...........] - ETA: 0s
#  84/114 [=====================>........] - ETA: 0s
#  92/114 [=======================>......] - ETA: 0s
# 101/114 [=========================>....] - ETA: 0s
# 109/114 [===========================>..] - ETA: 0s
# 114/114 [==============================] - 1s 6ms/step
# Sklearn binary metrics:
# accuracy: 0.9207
# precision: 0.4428
# recall: 0.9030
# f1: 0.5942
# mcc: 0.5994
# roc_auc: 0.9711
# pr_auc: 0.8008
# log_loss: 0.1937
# brier_score: 0.0581
#
# Confusion matrix:
#  [[97572  8267]
#  [  706  6569]]
#
# Classification report:
#                precision    recall  f1-score   support
#
#            0     0.9928    0.9219    0.9560    105839
#            1     0.4428    0.9030    0.5942      7275
#
#     accuracy                         0.9207    113114
#    macro avg     0.7178    0.9124    0.7751    113114
# weighted avg     0.9574    0.9207    0.9328    113114
