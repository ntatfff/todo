# %% [markdown]
# <a href="https://colab.research.google.com/github/ntatfff/todo/blob/202411241258/ColabRadiomicsFeatureExtractor.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import radiomics
import numpy as np
import SimpleITK as sitk
import radiomics.featureextractor
import os
import six
from os import path
import pandas as pd

def featureExtractor(fileId):
  imagePath = './dataset/BraTS2021_Training_Data/%s/%s_flair.nii.gz' % (fileId, fileId)
  image = sitk.ReadImage(imagePath)
  maskPath ='./dataset/BraTS2021_Training_Data/%s/%s_kernel5_tumor.nii.gz' % (fileId, fileId)
  mask = sitk.ReadImage(maskPath)

  kernel = 5
  settings = {}
  settings['kernelRadius'] = kernel
  settings['maskedKernel'] = False
  settings['voxelBatch'] = 40000
  extractor = radiomics.featureextractor.RadiomicsFeatureExtractor(**settings)
  extractor.disableAllFeatures()
  extractor.enableFeatureClassByName('glcm')

  featureMap = extractor.execute(image, mask, voxelBased=True)

  for featureName, featureValue in six.iteritems(featureMap):
    if isinstance(featureValue, sitk.Image):
      fileFolder = './dataset/glcm/kernel5-radius5/tumor/%s' % (fileId)
      if path.exists(fileFolder) == False:
        os.mkdir(fileFolder)
      sitk.WriteImage(featureValue, '%s/%s.nrrd' % (fileFolder, featureName))
      print('Computed %s, stored as "%s/%s.nrrd"' % (featureName, fileFolder, featureName))
    # else:
    #   print('%s: %s' % (featureName, featureValue))

monitorFilePath = './dataset/glcm/kernel5-radius5/tumor.glcm.monitor.csv'
monitor = pd.read_csv(monitorFilePath, index_col='no')
for i, row in monitor.iterrows():
  if row['done'] != 0:
    continue
  fileId = row['file']
  print('Starting %s' % (fileId))
  featureExtractor(fileId)
  monitor.at[i, 'done'] = 1
  monitor.to_csv(monitorFilePath)
# Out:
# Starting BraTS2021_00140
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# Computed original_glcm_Autocorrelation, stored as "./dataset/glcm/kernel5-radius5/tumor/BraTS2021_00140/original_glcm_Autocorrelation.nrrd"
# Computed original_glcm_ClusterProminence, stored as "./dataset/glcm/kernel5-radius5/tumor/BraTS2021_00140/original_glcm_ClusterProminence.nrrd"
# Computed original_glcm_ClusterShade, stored as "./dataset/glcm/kernel5-radius5/tumor/BraTS2021_00140/original_glcm_ClusterShade.nrrd"
# Computed original_glcm_ClusterTendency, stored as "./dataset/glcm/kernel5-radius5/tumor/BraTS2021_00140/original_glcm_ClusterTendency.nrrd"
# Computed original_glcm_Contrast, stored as "./dataset/glcm/kernel5-radius5/tumor/BraTS2021_00140/original_glcm_Contrast.nrrd"
# Computed original_glcm_Correlation, stored as "./dataset/glcm/kernel5-radius5/tumor/BraTS2021_00140/original_glcm_Correlation.nrrd"
# Computed original_glcm_DifferenceAverage, stored as "./dataset/glcm/kernel5-radius5/tumor/BraTS2021_00140/original_glcm_DifferenceAverage.nrrd"
# Computed original_glcm_DifferenceEntropy, stored as "./dataset/glcm/kernel5-radius5/tumor/BraTS2021_00140/original_glcm_DifferenceEntropy.nrrd"
# Computed original_glcm_DifferenceVariance, stored as "./dataset/glcm/kernel5-radius5/tumor/BraTS2021_00140/original_glcm_DifferenceVariance.nrrd"
# Computed original_glcm_Id, stored as "./dataset/glcm/kernel5-radius5/tumor/BraTS2021_00140/original_glcm_Id.nrrd"
# Computed original_glcm_Idm, stored as "./dataset/glcm/kernel5-radius5/tumor/BraTS2021_00140/original_glcm_Idm.nrrd"
# Computed original_glcm_Idmn, stored as "./dataset/glcm/kernel5-radius5/tumor/BraTS2021_00140/original_glcm_Idmn.nrrd"
# Computed original_glcm_Idn, stored as "./dataset/glcm/kernel5-radius5/tumor/BraTS2021_00140/original_glcm_Idn.nrrd"
# Computed original_glcm_Imc1, stored as "./dataset/glcm/kernel5-radius5/tumor/BraTS2021_00140/original_glcm_Imc1.nrrd"
# Computed original_glcm_Imc2, stored as "./dataset/glcm/kernel5-radius5/tumor/BraTS2021_00140/original_glcm_Imc2.nrrd"
# Computed original_glcm_InverseVariance, stored as "./dataset/glcm/kernel5-radius5/tumor/BraTS2021_00140/original_glcm_InverseVariance.nrrd"
# Computed original_glcm_JointAverage, stored as "./dataset/glcm/kernel5-radius5/tumor/BraTS2021_00140/original_glcm_JointAverage.nrrd"
# Computed original_glcm_JointEnergy, stored as "./dataset/glcm/kernel5-radius5/tumor/BraTS2021_00140/original_glcm_JointEnergy.nrrd"
# Computed original_glcm_JointEntropy, stored as "./dataset/glcm/kernel5-radius5/tumor/BraTS2021_00140/original_glcm_JointEntropy.nrrd"
# Computed original_glcm_MCC, stored as "./dataset/glcm/kernel5-radius5/tumor/BraTS2021_00140/original_glcm_MCC.nrrd"
# Computed original_glcm_MaximumProbability, stored as "./dataset/glcm/kernel5-radius5/tumor/BraTS2021_00140/original_glcm_MaximumProbability.nrrd"
# Computed original_glcm_SumAverage, stored as "./dataset/glcm/kernel5-radius5/tumor/BraTS2021_00140/original_glcm_SumAverage.nrrd"
# Computed original_glcm_SumEntropy, stored as "./dataset/glcm/kernel5-radius5/tumor/BraTS2021_00140/original_glcm_SumEntropy.nrrd"
# Computed original_glcm_SumSquares, stored as "./dataset/glcm/kernel5-radius5/tumor/BraTS2021_00140/original_glcm_SumSquares.nrrd"
# Starting BraTS2021_00142
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# Computed original_glcm_Autocorrelation, stored as "./dataset/glcm/kernel5-radius5/tumor/BraTS2021_00142/original_glcm_Autocorrelation.nrrd"
# Computed original_glcm_ClusterProminence, stored as "./dataset/glcm/kernel5-radius5/tumor/BraTS2021_00142/original_glcm_ClusterProminence.nrrd"
# Computed original_glcm_ClusterShade, stored as "./dataset/glcm/kernel5-radius5/tumor/BraTS2021_00142/original_glcm_ClusterShade.nrrd"
# Computed original_glcm_ClusterTendency, stored as "./dataset/glcm/kernel5-radius5/tumor/BraTS2021_00142/original_glcm_ClusterTendency.nrrd"
# Computed original_glcm_Contrast, stored as "./dataset/glcm/kernel5-radius5/tumor/BraTS2021_00142/original_glcm_Contrast.nrrd"
# Computed original_glcm_Correlation, stored as "./dataset/glcm/kernel5-radius5/tumor/BraTS2021_00142/original_glcm_Correlation.nrrd"
# Computed original_glcm_DifferenceAverage, stored as "./dataset/glcm/kernel5-radius5/tumor/BraTS2021_00142/original_glcm_DifferenceAverage.nrrd"
# Computed original_glcm_DifferenceEntropy, stored as "./dataset/glcm/kernel5-radius5/tumor/BraTS2021_00142/original_glcm_DifferenceEntropy.nrrd"
# Computed original_glcm_DifferenceVariance, stored as "./dataset/glcm/kernel5-radius5/tumor/BraTS2021_00142/original_glcm_DifferenceVariance.nrrd"
# Computed original_glcm_Id, stored as "./dataset/glcm/kernel5-radius5/tumor/BraTS2021_00142/original_glcm_Id.nrrd"
# Computed original_glcm_Idm, stored as "./dataset/glcm/kernel5-radius5/tumor/BraTS2021_00142/original_glcm_Idm.nrrd"
# Computed original_glcm_Idmn, stored as "./dataset/glcm/kernel5-radius5/tumor/BraTS2021_00142/original_glcm_Idmn.nrrd"
# Computed original_glcm_Idn, stored as "./dataset/glcm/kernel5-radius5/tumor/BraTS2021_00142/original_glcm_Idn.nrrd"
# Computed original_glcm_Imc1, stored as "./dataset/glcm/kernel5-radius5/tumor/BraTS2021_00142/original_glcm_Imc1.nrrd"
# Computed original_glcm_Imc2, stored as "./dataset/glcm/kernel5-radius5/tumor/BraTS2021_00142/original_glcm_Imc2.nrrd"
# Computed original_glcm_InverseVariance, stored as "./dataset/glcm/kernel5-radius5/tumor/BraTS2021_00142/original_glcm_InverseVariance.nrrd"
# Computed original_glcm_JointAverage, stored as "./dataset/glcm/kernel5-radius5/tumor/BraTS2021_00142/original_glcm_JointAverage.nrrd"
# Computed original_glcm_JointEnergy, stored as "./dataset/glcm/kernel5-radius5/tumor/BraTS2021_00142/original_glcm_JointEnergy.nrrd"
# Computed original_glcm_JointEntropy, stored as "./dataset/glcm/kernel5-radius5/tumor/BraTS2021_00142/original_glcm_JointEntropy.nrrd"
# Computed original_glcm_MCC, stored as "./dataset/glcm/kernel5-radius5/tumor/BraTS2021_00142/original_glcm_MCC.nrrd"
# Computed original_glcm_MaximumProbability, stored as "./dataset/glcm/kernel5-radius5/tumor/BraTS2021_00142/original_glcm_MaximumProbability.nrrd"
# Computed original_glcm_SumAverage, stored as "./dataset/glcm/kernel5-radius5/tumor/BraTS2021_00142/original_glcm_SumAverage.nrrd"
# Computed original_glcm_SumEntropy, stored as "./dataset/glcm/kernel5-radius5/tumor/BraTS2021_00142/original_glcm_SumEntropy.nrrd"
# Computed original_glcm_SumSquares, stored as "./dataset/glcm/kernel5-radius5/tumor/BraTS2021_00142/original_glcm_SumSquares.nrrd"
# Starting BraTS2021_00143
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# Computed original_glcm_Autocorrelation, stored as "./dataset/glcm/kernel5-radius5/tumor/BraTS2021_00143/original_glcm_Autocorrelation.nrrd"
# Computed original_glcm_ClusterProminence, stored as "./dataset/glcm/kernel5-radius5/tumor/BraTS2021_00143/original_glcm_ClusterProminence.nrrd"
# Computed original_glcm_ClusterShade, stored as "./dataset/glcm/kernel5-radius5/tumor/BraTS2021_00143/original_glcm_ClusterShade.nrrd"
# Computed original_glcm_ClusterTendency, stored as "./dataset/glcm/kernel5-radius5/tumor/BraTS2021_00143/original_glcm_ClusterTendency.nrrd"
# Computed original_glcm_Contrast, stored as "./dataset/glcm/kernel5-radius5/tumor/BraTS2021_00143/original_glcm_Contrast.nrrd"
# Computed original_glcm_Correlation, stored as "./dataset/glcm/kernel5-radius5/tumor/BraTS2021_00143/original_glcm_Correlation.nrrd"
# Computed original_glcm_DifferenceAverage, stored as "./dataset/glcm/kernel5-radius5/tumor/BraTS2021_00143/original_glcm_DifferenceAverage.nrrd"
# Computed original_glcm_DifferenceEntropy, stored as "./dataset/glcm/kernel5-radius5/tumor/BraTS2021_00143/original_glcm_DifferenceEntropy.nrrd"
# Computed original_glcm_DifferenceVariance, stored as "./dataset/glcm/kernel5-radius5/tumor/BraTS2021_00143/original_glcm_DifferenceVariance.nrrd"
# Computed original_glcm_Id, stored as "./dataset/glcm/kernel5-radius5/tumor/BraTS2021_00143/original_glcm_Id.nrrd"
# Computed original_glcm_Idm, stored as "./dataset/glcm/kernel5-radius5/tumor/BraTS2021_00143/original_glcm_Idm.nrrd"
# Computed original_glcm_Idmn, stored as "./dataset/glcm/kernel5-radius5/tumor/BraTS2021_00143/original_glcm_Idmn.nrrd"
# Computed original_glcm_Idn, stored as "./dataset/glcm/kernel5-radius5/tumor/BraTS2021_00143/original_glcm_Idn.nrrd"
# Computed original_glcm_Imc1, stored as "./dataset/glcm/kernel5-radius5/tumor/BraTS2021_00143/original_glcm_Imc1.nrrd"
# Computed original_glcm_Imc2, stored as "./dataset/glcm/kernel5-radius5/tumor/BraTS2021_00143/original_glcm_Imc2.nrrd"
# Computed original_glcm_InverseVariance, stored as "./dataset/glcm/kernel5-radius5/tumor/BraTS2021_00143/original_glcm_InverseVariance.nrrd"
# Computed original_glcm_JointAverage, stored as "./dataset/glcm/kernel5-radius5/tumor/BraTS2021_00143/original_glcm_JointAverage.nrrd"
# Computed original_glcm_JointEnergy, stored as "./dataset/glcm/kernel5-radius5/tumor/BraTS2021_00143/original_glcm_JointEnergy.nrrd"
# Computed original_glcm_JointEntropy, stored as "./dataset/glcm/kernel5-radius5/tumor/BraTS2021_00143/original_glcm_JointEntropy.nrrd"
# Computed original_glcm_MCC, stored as "./dataset/glcm/kernel5-radius5/tumor/BraTS2021_00143/original_glcm_MCC.nrrd"
# Computed original_glcm_MaximumProbability, stored as "./dataset/glcm/kernel5-radius5/tumor/BraTS2021_00143/original_glcm_MaximumProbability.nrrd"
# Computed original_glcm_SumAverage, stored as "./dataset/glcm/kernel5-radius5/tumor/BraTS2021_00143/original_glcm_SumAverage.nrrd"
# Computed original_glcm_SumEntropy, stored as "./dataset/glcm/kernel5-radius5/tumor/BraTS2021_00143/original_glcm_SumEntropy.nrrd"
# Computed original_glcm_SumSquares, stored as "./dataset/glcm/kernel5-radius5/tumor/BraTS2021_00143/original_glcm_SumSquares.nrrd"
# Starting BraTS2021_00144
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# Computed original_glcm_Autocorrelation, stored as "./dataset/glcm/kernel5-radius5/tumor/BraTS2021_00144/original_glcm_Autocorrelation.nrrd"
# Computed original_glcm_ClusterProminence, stored as "./dataset/glcm/kernel5-radius5/tumor/BraTS2021_00144/original_glcm_ClusterProminence.nrrd"
# Computed original_glcm_ClusterShade, stored as "./dataset/glcm/kernel5-radius5/tumor/BraTS2021_00144/original_glcm_ClusterShade.nrrd"
# Computed original_glcm_ClusterTendency, stored as "./dataset/glcm/kernel5-radius5/tumor/BraTS2021_00144/original_glcm_ClusterTendency.nrrd"
# Computed original_glcm_Contrast, stored as "./dataset/glcm/kernel5-radius5/tumor/BraTS2021_00144/original_glcm_Contrast.nrrd"
# Computed original_glcm_Correlation, stored as "./dataset/glcm/kernel5-radius5/tumor/BraTS2021_00144/original_glcm_Correlation.nrrd"
# Computed original_glcm_DifferenceAverage, stored as "./dataset/glcm/kernel5-radius5/tumor/BraTS2021_00144/original_glcm_DifferenceAverage.nrrd"
# Computed original_glcm_DifferenceEntropy, stored as "./dataset/glcm/kernel5-radius5/tumor/BraTS2021_00144/original_glcm_DifferenceEntropy.nrrd"
# Computed original_glcm_DifferenceVariance, stored as "./dataset/glcm/kernel5-radius5/tumor/BraTS2021_00144/original_glcm_DifferenceVariance.nrrd"
# Computed original_glcm_Id, stored as "./dataset/glcm/kernel5-radius5/tumor/BraTS2021_00144/original_glcm_Id.nrrd"
# Computed original_glcm_Idm, stored as "./dataset/glcm/kernel5-radius5/tumor/BraTS2021_00144/original_glcm_Idm.nrrd"
# Computed original_glcm_Idmn, stored as "./dataset/glcm/kernel5-radius5/tumor/BraTS2021_00144/original_glcm_Idmn.nrrd"
# Computed original_glcm_Idn, stored as "./dataset/glcm/kernel5-radius5/tumor/BraTS2021_00144/original_glcm_Idn.nrrd"
# Computed original_glcm_Imc1, stored as "./dataset/glcm/kernel5-radius5/tumor/BraTS2021_00144/original_glcm_Imc1.nrrd"
# Computed original_glcm_Imc2, stored as "./dataset/glcm/kernel5-radius5/tumor/BraTS2021_00144/original_glcm_Imc2.nrrd"
# Computed original_glcm_InverseVariance, stored as "./dataset/glcm/kernel5-radius5/tumor/BraTS2021_00144/original_glcm_InverseVariance.nrrd"
# Computed original_glcm_JointAverage, stored as "./dataset/glcm/kernel5-radius5/tumor/BraTS2021_00144/original_glcm_JointAverage.nrrd"
# Computed original_glcm_JointEnergy, stored as "./dataset/glcm/kernel5-radius5/tumor/BraTS2021_00144/original_glcm_JointEnergy.nrrd"
# Computed original_glcm_JointEntropy, stored as "./dataset/glcm/kernel5-radius5/tumor/BraTS2021_00144/original_glcm_JointEntropy.nrrd"
# Computed original_glcm_MCC, stored as "./dataset/glcm/kernel5-radius5/tumor/BraTS2021_00144/original_glcm_MCC.nrrd"
# Computed original_glcm_MaximumProbability, stored as "./dataset/glcm/kernel5-radius5/tumor/BraTS2021_00144/original_glcm_MaximumProbability.nrrd"
# Computed original_glcm_SumAverage, stored as "./dataset/glcm/kernel5-radius5/tumor/BraTS2021_00144/original_glcm_SumAverage.nrrd"
# Computed original_glcm_SumEntropy, stored as "./dataset/glcm/kernel5-radius5/tumor/BraTS2021_00144/original_glcm_SumEntropy.nrrd"
# Computed original_glcm_SumSquares, stored as "./dataset/glcm/kernel5-radius5/tumor/BraTS2021_00144/original_glcm_SumSquares.nrrd"
# Starting BraTS2021_00146
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# Computed original_glcm_Autocorrelation, stored as "./dataset/glcm/kernel5-radius5/tumor/BraTS2021_00146/original_glcm_Autocorrelation.nrrd"
# Computed original_glcm_ClusterProminence, stored as "./dataset/glcm/kernel5-radius5/tumor/BraTS2021_00146/original_glcm_ClusterProminence.nrrd"
# Computed original_glcm_ClusterShade, stored as "./dataset/glcm/kernel5-radius5/tumor/BraTS2021_00146/original_glcm_ClusterShade.nrrd"
# Computed original_glcm_ClusterTendency, stored as "./dataset/glcm/kernel5-radius5/tumor/BraTS2021_00146/original_glcm_ClusterTendency.nrrd"
# Computed original_glcm_Contrast, stored as "./dataset/glcm/kernel5-radius5/tumor/BraTS2021_00146/original_glcm_Contrast.nrrd"
# Computed original_glcm_Correlation, stored as "./dataset/glcm/kernel5-radius5/tumor/BraTS2021_00146/original_glcm_Correlation.nrrd"
# Computed original_glcm_DifferenceAverage, stored as "./dataset/glcm/kernel5-radius5/tumor/BraTS2021_00146/original_glcm_DifferenceAverage.nrrd"
# Computed original_glcm_DifferenceEntropy, stored as "./dataset/glcm/kernel5-radius5/tumor/BraTS2021_00146/original_glcm_DifferenceEntropy.nrrd"
# Computed original_glcm_DifferenceVariance, stored as "./dataset/glcm/kernel5-radius5/tumor/BraTS2021_00146/original_glcm_DifferenceVariance.nrrd"
# Computed original_glcm_Id, stored as "./dataset/glcm/kernel5-radius5/tumor/BraTS2021_00146/original_glcm_Id.nrrd"
# Computed original_glcm_Idm, stored as "./dataset/glcm/kernel5-radius5/tumor/BraTS2021_00146/original_glcm_Idm.nrrd"
# Computed original_glcm_Idmn, stored as "./dataset/glcm/kernel5-radius5/tumor/BraTS2021_00146/original_glcm_Idmn.nrrd"
# Computed original_glcm_Idn, stored as "./dataset/glcm/kernel5-radius5/tumor/BraTS2021_00146/original_glcm_Idn.nrrd"
# Computed original_glcm_Imc1, stored as "./dataset/glcm/kernel5-radius5/tumor/BraTS2021_00146/original_glcm_Imc1.nrrd"
# Computed original_glcm_Imc2, stored as "./dataset/glcm/kernel5-radius5/tumor/BraTS2021_00146/original_glcm_Imc2.nrrd"
# Computed original_glcm_InverseVariance, stored as "./dataset/glcm/kernel5-radius5/tumor/BraTS2021_00146/original_glcm_InverseVariance.nrrd"
# Computed original_glcm_JointAverage, stored as "./dataset/glcm/kernel5-radius5/tumor/BraTS2021_00146/original_glcm_JointAverage.nrrd"
# Computed original_glcm_JointEnergy, stored as "./dataset/glcm/kernel5-radius5/tumor/BraTS2021_00146/original_glcm_JointEnergy.nrrd"
# Computed original_glcm_JointEntropy, stored as "./dataset/glcm/kernel5-radius5/tumor/BraTS2021_00146/original_glcm_JointEntropy.nrrd"
# Computed original_glcm_MCC, stored as "./dataset/glcm/kernel5-radius5/tumor/BraTS2021_00146/original_glcm_MCC.nrrd"
# Computed original_glcm_MaximumProbability, stored as "./dataset/glcm/kernel5-radius5/tumor/BraTS2021_00146/original_glcm_MaximumProbability.nrrd"
# Computed original_glcm_SumAverage, stored as "./dataset/glcm/kernel5-radius5/tumor/BraTS2021_00146/original_glcm_SumAverage.nrrd"
# Computed original_glcm_SumEntropy, stored as "./dataset/glcm/kernel5-radius5/tumor/BraTS2021_00146/original_glcm_SumEntropy.nrrd"
# Computed original_glcm_SumSquares, stored as "./dataset/glcm/kernel5-radius5/tumor/BraTS2021_00146/original_glcm_SumSquares.nrrd"
# Starting BraTS2021_00147
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# Computed original_glcm_Autocorrelation, stored as "./dataset/glcm/kernel5-radius5/tumor/BraTS2021_00147/original_glcm_Autocorrelation.nrrd"
# Computed original_glcm_ClusterProminence, stored as "./dataset/glcm/kernel5-radius5/tumor/BraTS2021_00147/original_glcm_ClusterProminence.nrrd"
# Computed original_glcm_ClusterShade, stored as "./dataset/glcm/kernel5-radius5/tumor/BraTS2021_00147/original_glcm_ClusterShade.nrrd"
# Computed original_glcm_ClusterTendency, stored as "./dataset/glcm/kernel5-radius5/tumor/BraTS2021_00147/original_glcm_ClusterTendency.nrrd"
# Computed original_glcm_Contrast, stored as "./dataset/glcm/kernel5-radius5/tumor/BraTS2021_00147/original_glcm_Contrast.nrrd"
# Computed original_glcm_Correlation, stored as "./dataset/glcm/kernel5-radius5/tumor/BraTS2021_00147/original_glcm_Correlation.nrrd"
# Computed original_glcm_DifferenceAverage, stored as "./dataset/glcm/kernel5-radius5/tumor/BraTS2021_00147/original_glcm_DifferenceAverage.nrrd"
# Computed original_glcm_DifferenceEntropy, stored as "./dataset/glcm/kernel5-radius5/tumor/BraTS2021_00147/original_glcm_DifferenceEntropy.nrrd"
# Computed original_glcm_DifferenceVariance, stored as "./dataset/glcm/kernel5-radius5/tumor/BraTS2021_00147/original_glcm_DifferenceVariance.nrrd"
# Computed original_glcm_Id, stored as "./dataset/glcm/kernel5-radius5/tumor/BraTS2021_00147/original_glcm_Id.nrrd"
# Computed original_glcm_Idm, stored as "./dataset/glcm/kernel5-radius5/tumor/BraTS2021_00147/original_glcm_Idm.nrrd"
# Computed original_glcm_Idmn, stored as "./dataset/glcm/kernel5-radius5/tumor/BraTS2021_00147/original_glcm_Idmn.nrrd"
# Computed original_glcm_Idn, stored as "./dataset/glcm/kernel5-radius5/tumor/BraTS2021_00147/original_glcm_Idn.nrrd"
# Computed original_glcm_Imc1, stored as "./dataset/glcm/kernel5-radius5/tumor/BraTS2021_00147/original_glcm_Imc1.nrrd"
# Computed original_glcm_Imc2, stored as "./dataset/glcm/kernel5-radius5/tumor/BraTS2021_00147/original_glcm_Imc2.nrrd"
# Computed original_glcm_InverseVariance, stored as "./dataset/glcm/kernel5-radius5/tumor/BraTS2021_00147/original_glcm_InverseVariance.nrrd"
# Computed original_glcm_JointAverage, stored as "./dataset/glcm/kernel5-radius5/tumor/BraTS2021_00147/original_glcm_JointAverage.nrrd"
# Computed original_glcm_JointEnergy, stored as "./dataset/glcm/kernel5-radius5/tumor/BraTS2021_00147/original_glcm_JointEnergy.nrrd"
# Computed original_glcm_JointEntropy, stored as "./dataset/glcm/kernel5-radius5/tumor/BraTS2021_00147/original_glcm_JointEntropy.nrrd"
# Computed original_glcm_MCC, stored as "./dataset/glcm/kernel5-radius5/tumor/BraTS2021_00147/original_glcm_MCC.nrrd"
# Computed original_glcm_MaximumProbability, stored as "./dataset/glcm/kernel5-radius5/tumor/BraTS2021_00147/original_glcm_MaximumProbability.nrrd"
# Computed original_glcm_SumAverage, stored as "./dataset/glcm/kernel5-radius5/tumor/BraTS2021_00147/original_glcm_SumAverage.nrrd"
# Computed original_glcm_SumEntropy, stored as "./dataset/glcm/kernel5-radius5/tumor/BraTS2021_00147/original_glcm_SumEntropy.nrrd"
# Computed original_glcm_SumSquares, stored as "./dataset/glcm/kernel5-radius5/tumor/BraTS2021_00147/original_glcm_SumSquares.nrrd"
# Starting BraTS2021_00148
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# Computed original_glcm_Autocorrelation, stored as "./dataset/glcm/kernel5-radius5/tumor/BraTS2021_00148/original_glcm_Autocorrelation.nrrd"
# Computed original_glcm_ClusterProminence, stored as "./dataset/glcm/kernel5-radius5/tumor/BraTS2021_00148/original_glcm_ClusterProminence.nrrd"
# Computed original_glcm_ClusterShade, stored as "./dataset/glcm/kernel5-radius5/tumor/BraTS2021_00148/original_glcm_ClusterShade.nrrd"
# Computed original_glcm_ClusterTendency, stored as "./dataset/glcm/kernel5-radius5/tumor/BraTS2021_00148/original_glcm_ClusterTendency.nrrd"
# Computed original_glcm_Contrast, stored as "./dataset/glcm/kernel5-radius5/tumor/BraTS2021_00148/original_glcm_Contrast.nrrd"
# Computed original_glcm_Correlation, stored as "./dataset/glcm/kernel5-radius5/tumor/BraTS2021_00148/original_glcm_Correlation.nrrd"
# Computed original_glcm_DifferenceAverage, stored as "./dataset/glcm/kernel5-radius5/tumor/BraTS2021_00148/original_glcm_DifferenceAverage.nrrd"
# Computed original_glcm_DifferenceEntropy, stored as "./dataset/glcm/kernel5-radius5/tumor/BraTS2021_00148/original_glcm_DifferenceEntropy.nrrd"
# Computed original_glcm_DifferenceVariance, stored as "./dataset/glcm/kernel5-radius5/tumor/BraTS2021_00148/original_glcm_DifferenceVariance.nrrd"
# Computed original_glcm_Id, stored as "./dataset/glcm/kernel5-radius5/tumor/BraTS2021_00148/original_glcm_Id.nrrd"
# Computed original_glcm_Idm, stored as "./dataset/glcm/kernel5-radius5/tumor/BraTS2021_00148/original_glcm_Idm.nrrd"
# Computed original_glcm_Idmn, stored as "./dataset/glcm/kernel5-radius5/tumor/BraTS2021_00148/original_glcm_Idmn.nrrd"
# Computed original_glcm_Idn, stored as "./dataset/glcm/kernel5-radius5/tumor/BraTS2021_00148/original_glcm_Idn.nrrd"
# Computed original_glcm_Imc1, stored as "./dataset/glcm/kernel5-radius5/tumor/BraTS2021_00148/original_glcm_Imc1.nrrd"
# Computed original_glcm_Imc2, stored as "./dataset/glcm/kernel5-radius5/tumor/BraTS2021_00148/original_glcm_Imc2.nrrd"
# Computed original_glcm_InverseVariance, stored as "./dataset/glcm/kernel5-radius5/tumor/BraTS2021_00148/original_glcm_InverseVariance.nrrd"
# Computed original_glcm_JointAverage, stored as "./dataset/glcm/kernel5-radius5/tumor/BraTS2021_00148/original_glcm_JointAverage.nrrd"
# Computed original_glcm_JointEnergy, stored as "./dataset/glcm/kernel5-radius5/tumor/BraTS2021_00148/original_glcm_JointEnergy.nrrd"
# Computed original_glcm_JointEntropy, stored as "./dataset/glcm/kernel5-radius5/tumor/BraTS2021_00148/original_glcm_JointEntropy.nrrd"
# Computed original_glcm_MCC, stored as "./dataset/glcm/kernel5-radius5/tumor/BraTS2021_00148/original_glcm_MCC.nrrd"
# Computed original_glcm_MaximumProbability, stored as "./dataset/glcm/kernel5-radius5/tumor/BraTS2021_00148/original_glcm_MaximumProbability.nrrd"
# Computed original_glcm_SumAverage, stored as "./dataset/glcm/kernel5-radius5/tumor/BraTS2021_00148/original_glcm_SumAverage.nrrd"
# Computed original_glcm_SumEntropy, stored as "./dataset/glcm/kernel5-radius5/tumor/BraTS2021_00148/original_glcm_SumEntropy.nrrd"
# Computed original_glcm_SumSquares, stored as "./dataset/glcm/kernel5-radius5/tumor/BraTS2021_00148/original_glcm_SumSquares.nrrd"
# Starting BraTS2021_00149
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# Computed original_glcm_Autocorrelation, stored as "./dataset/glcm/kernel5-radius5/tumor/BraTS2021_00149/original_glcm_Autocorrelation.nrrd"
# Computed original_glcm_ClusterProminence, stored as "./dataset/glcm/kernel5-radius5/tumor/BraTS2021_00149/original_glcm_ClusterProminence.nrrd"
# Computed original_glcm_ClusterShade, stored as "./dataset/glcm/kernel5-radius5/tumor/BraTS2021_00149/original_glcm_ClusterShade.nrrd"
# Computed original_glcm_ClusterTendency, stored as "./dataset/glcm/kernel5-radius5/tumor/BraTS2021_00149/original_glcm_ClusterTendency.nrrd"
# Computed original_glcm_Contrast, stored as "./dataset/glcm/kernel5-radius5/tumor/BraTS2021_00149/original_glcm_Contrast.nrrd"
# Computed original_glcm_Correlation, stored as "./dataset/glcm/kernel5-radius5/tumor/BraTS2021_00149/original_glcm_Correlation.nrrd"
# Computed original_glcm_DifferenceAverage, stored as "./dataset/glcm/kernel5-radius5/tumor/BraTS2021_00149/original_glcm_DifferenceAverage.nrrd"
# Computed original_glcm_DifferenceEntropy, stored as "./dataset/glcm/kernel5-radius5/tumor/BraTS2021_00149/original_glcm_DifferenceEntropy.nrrd"
# Computed original_glcm_DifferenceVariance, stored as "./dataset/glcm/kernel5-radius5/tumor/BraTS2021_00149/original_glcm_DifferenceVariance.nrrd"
# Computed original_glcm_Id, stored as "./dataset/glcm/kernel5-radius5/tumor/BraTS2021_00149/original_glcm_Id.nrrd"
# Computed original_glcm_Idm, stored as "./dataset/glcm/kernel5-radius5/tumor/BraTS2021_00149/original_glcm_Idm.nrrd"
# Computed original_glcm_Idmn, stored as "./dataset/glcm/kernel5-radius5/tumor/BraTS2021_00149/original_glcm_Idmn.nrrd"
# Computed original_glcm_Idn, stored as "./dataset/glcm/kernel5-radius5/tumor/BraTS2021_00149/original_glcm_Idn.nrrd"
# Computed original_glcm_Imc1, stored as "./dataset/glcm/kernel5-radius5/tumor/BraTS2021_00149/original_glcm_Imc1.nrrd"
# Computed original_glcm_Imc2, stored as "./dataset/glcm/kernel5-radius5/tumor/BraTS2021_00149/original_glcm_Imc2.nrrd"
# Computed original_glcm_InverseVariance, stored as "./dataset/glcm/kernel5-radius5/tumor/BraTS2021_00149/original_glcm_InverseVariance.nrrd"
# Computed original_glcm_JointAverage, stored as "./dataset/glcm/kernel5-radius5/tumor/BraTS2021_00149/original_glcm_JointAverage.nrrd"
# Computed original_glcm_JointEnergy, stored as "./dataset/glcm/kernel5-radius5/tumor/BraTS2021_00149/original_glcm_JointEnergy.nrrd"
# Computed original_glcm_JointEntropy, stored as "./dataset/glcm/kernel5-radius5/tumor/BraTS2021_00149/original_glcm_JointEntropy.nrrd"
# Computed original_glcm_MCC, stored as "./dataset/glcm/kernel5-radius5/tumor/BraTS2021_00149/original_glcm_MCC.nrrd"
# Computed original_glcm_MaximumProbability, stored as "./dataset/glcm/kernel5-radius5/tumor/BraTS2021_00149/original_glcm_MaximumProbability.nrrd"
# Computed original_glcm_SumAverage, stored as "./dataset/glcm/kernel5-radius5/tumor/BraTS2021_00149/original_glcm_SumAverage.nrrd"
# Computed original_glcm_SumEntropy, stored as "./dataset/glcm/kernel5-radius5/tumor/BraTS2021_00149/original_glcm_SumEntropy.nrrd"
# Computed original_glcm_SumSquares, stored as "./dataset/glcm/kernel5-radius5/tumor/BraTS2021_00149/original_glcm_SumSquares.nrrd"
# Starting BraTS2021_00150
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# Computed original_glcm_Autocorrelation, stored as "./dataset/glcm/kernel5-radius5/tumor/BraTS2021_00150/original_glcm_Autocorrelation.nrrd"
# Computed original_glcm_ClusterProminence, stored as "./dataset/glcm/kernel5-radius5/tumor/BraTS2021_00150/original_glcm_ClusterProminence.nrrd"
# Computed original_glcm_ClusterShade, stored as "./dataset/glcm/kernel5-radius5/tumor/BraTS2021_00150/original_glcm_ClusterShade.nrrd"
# Computed original_glcm_ClusterTendency, stored as "./dataset/glcm/kernel5-radius5/tumor/BraTS2021_00150/original_glcm_ClusterTendency.nrrd"
# Computed original_glcm_Contrast, stored as "./dataset/glcm/kernel5-radius5/tumor/BraTS2021_00150/original_glcm_Contrast.nrrd"
# Computed original_glcm_Correlation, stored as "./dataset/glcm/kernel5-radius5/tumor/BraTS2021_00150/original_glcm_Correlation.nrrd"
# Computed original_glcm_DifferenceAverage, stored as "./dataset/glcm/kernel5-radius5/tumor/BraTS2021_00150/original_glcm_DifferenceAverage.nrrd"
# Computed original_glcm_DifferenceEntropy, stored as "./dataset/glcm/kernel5-radius5/tumor/BraTS2021_00150/original_glcm_DifferenceEntropy.nrrd"
# Computed original_glcm_DifferenceVariance, stored as "./dataset/glcm/kernel5-radius5/tumor/BraTS2021_00150/original_glcm_DifferenceVariance.nrrd"
# Computed original_glcm_Id, stored as "./dataset/glcm/kernel5-radius5/tumor/BraTS2021_00150/original_glcm_Id.nrrd"
# Computed original_glcm_Idm, stored as "./dataset/glcm/kernel5-radius5/tumor/BraTS2021_00150/original_glcm_Idm.nrrd"
# Computed original_glcm_Idmn, stored as "./dataset/glcm/kernel5-radius5/tumor/BraTS2021_00150/original_glcm_Idmn.nrrd"
# Computed original_glcm_Idn, stored as "./dataset/glcm/kernel5-radius5/tumor/BraTS2021_00150/original_glcm_Idn.nrrd"
# Computed original_glcm_Imc1, stored as "./dataset/glcm/kernel5-radius5/tumor/BraTS2021_00150/original_glcm_Imc1.nrrd"
# Computed original_glcm_Imc2, stored as "./dataset/glcm/kernel5-radius5/tumor/BraTS2021_00150/original_glcm_Imc2.nrrd"
# Computed original_glcm_InverseVariance, stored as "./dataset/glcm/kernel5-radius5/tumor/BraTS2021_00150/original_glcm_InverseVariance.nrrd"
# Computed original_glcm_JointAverage, stored as "./dataset/glcm/kernel5-radius5/tumor/BraTS2021_00150/original_glcm_JointAverage.nrrd"
# Computed original_glcm_JointEnergy, stored as "./dataset/glcm/kernel5-radius5/tumor/BraTS2021_00150/original_glcm_JointEnergy.nrrd"
# Computed original_glcm_JointEntropy, stored as "./dataset/glcm/kernel5-radius5/tumor/BraTS2021_00150/original_glcm_JointEntropy.nrrd"
# Computed original_glcm_MCC, stored as "./dataset/glcm/kernel5-radius5/tumor/BraTS2021_00150/original_glcm_MCC.nrrd"
# Computed original_glcm_MaximumProbability, stored as "./dataset/glcm/kernel5-radius5/tumor/BraTS2021_00150/original_glcm_MaximumProbability.nrrd"
# Computed original_glcm_SumAverage, stored as "./dataset/glcm/kernel5-radius5/tumor/BraTS2021_00150/original_glcm_SumAverage.nrrd"
# Computed original_glcm_SumEntropy, stored as "./dataset/glcm/kernel5-radius5/tumor/BraTS2021_00150/original_glcm_SumEntropy.nrrd"
# Computed original_glcm_SumSquares, stored as "./dataset/glcm/kernel5-radius5/tumor/BraTS2021_00150/original_glcm_SumSquares.nrrd"
# Starting BraTS2021_00151
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# Computed original_glcm_Autocorrelation, stored as "./dataset/glcm/kernel5-radius5/tumor/BraTS2021_00151/original_glcm_Autocorrelation.nrrd"
# Computed original_glcm_ClusterProminence, stored as "./dataset/glcm/kernel5-radius5/tumor/BraTS2021_00151/original_glcm_ClusterProminence.nrrd"
# Computed original_glcm_ClusterShade, stored as "./dataset/glcm/kernel5-radius5/tumor/BraTS2021_00151/original_glcm_ClusterShade.nrrd"
# Computed original_glcm_ClusterTendency, stored as "./dataset/glcm/kernel5-radius5/tumor/BraTS2021_00151/original_glcm_ClusterTendency.nrrd"
# Computed original_glcm_Contrast, stored as "./dataset/glcm/kernel5-radius5/tumor/BraTS2021_00151/original_glcm_Contrast.nrrd"
# Computed original_glcm_Correlation, stored as "./dataset/glcm/kernel5-radius5/tumor/BraTS2021_00151/original_glcm_Correlation.nrrd"
# Computed original_glcm_DifferenceAverage, stored as "./dataset/glcm/kernel5-radius5/tumor/BraTS2021_00151/original_glcm_DifferenceAverage.nrrd"
# Computed original_glcm_DifferenceEntropy, stored as "./dataset/glcm/kernel5-radius5/tumor/BraTS2021_00151/original_glcm_DifferenceEntropy.nrrd"
# Computed original_glcm_DifferenceVariance, stored as "./dataset/glcm/kernel5-radius5/tumor/BraTS2021_00151/original_glcm_DifferenceVariance.nrrd"
# Computed original_glcm_Id, stored as "./dataset/glcm/kernel5-radius5/tumor/BraTS2021_00151/original_glcm_Id.nrrd"
# Computed original_glcm_Idm, stored as "./dataset/glcm/kernel5-radius5/tumor/BraTS2021_00151/original_glcm_Idm.nrrd"
# Computed original_glcm_Idmn, stored as "./dataset/glcm/kernel5-radius5/tumor/BraTS2021_00151/original_glcm_Idmn.nrrd"
# Computed original_glcm_Idn, stored as "./dataset/glcm/kernel5-radius5/tumor/BraTS2021_00151/original_glcm_Idn.nrrd"
# Computed original_glcm_Imc1, stored as "./dataset/glcm/kernel5-radius5/tumor/BraTS2021_00151/original_glcm_Imc1.nrrd"
# Computed original_glcm_Imc2, stored as "./dataset/glcm/kernel5-radius5/tumor/BraTS2021_00151/original_glcm_Imc2.nrrd"
# Computed original_glcm_InverseVariance, stored as "./dataset/glcm/kernel5-radius5/tumor/BraTS2021_00151/original_glcm_InverseVariance.nrrd"
# Computed original_glcm_JointAverage, stored as "./dataset/glcm/kernel5-radius5/tumor/BraTS2021_00151/original_glcm_JointAverage.nrrd"
# Computed original_glcm_JointEnergy, stored as "./dataset/glcm/kernel5-radius5/tumor/BraTS2021_00151/original_glcm_JointEnergy.nrrd"
# Computed original_glcm_JointEntropy, stored as "./dataset/glcm/kernel5-radius5/tumor/BraTS2021_00151/original_glcm_JointEntropy.nrrd"
# Computed original_glcm_MCC, stored as "./dataset/glcm/kernel5-radius5/tumor/BraTS2021_00151/original_glcm_MCC.nrrd"
# Computed original_glcm_MaximumProbability, stored as "./dataset/glcm/kernel5-radius5/tumor/BraTS2021_00151/original_glcm_MaximumProbability.nrrd"
# Computed original_glcm_SumAverage, stored as "./dataset/glcm/kernel5-radius5/tumor/BraTS2021_00151/original_glcm_SumAverage.nrrd"
# Computed original_glcm_SumEntropy, stored as "./dataset/glcm/kernel5-radius5/tumor/BraTS2021_00151/original_glcm_SumEntropy.nrrd"
# Computed original_glcm_SumSquares, stored as "./dataset/glcm/kernel5-radius5/tumor/BraTS2021_00151/original_glcm_SumSquares.nrrd"
# Starting BraTS2021_00152
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# Computed original_glcm_Autocorrelation, stored as "./dataset/glcm/kernel5-radius5/tumor/BraTS2021_00152/original_glcm_Autocorrelation.nrrd"
# Computed original_glcm_ClusterProminence, stored as "./dataset/glcm/kernel5-radius5/tumor/BraTS2021_00152/original_glcm_ClusterProminence.nrrd"
# Computed original_glcm_ClusterShade, stored as "./dataset/glcm/kernel5-radius5/tumor/BraTS2021_00152/original_glcm_ClusterShade.nrrd"
# Computed original_glcm_ClusterTendency, stored as "./dataset/glcm/kernel5-radius5/tumor/BraTS2021_00152/original_glcm_ClusterTendency.nrrd"
# Computed original_glcm_Contrast, stored as "./dataset/glcm/kernel5-radius5/tumor/BraTS2021_00152/original_glcm_Contrast.nrrd"
# Computed original_glcm_Correlation, stored as "./dataset/glcm/kernel5-radius5/tumor/BraTS2021_00152/original_glcm_Correlation.nrrd"
# Computed original_glcm_DifferenceAverage, stored as "./dataset/glcm/kernel5-radius5/tumor/BraTS2021_00152/original_glcm_DifferenceAverage.nrrd"
# Computed original_glcm_DifferenceEntropy, stored as "./dataset/glcm/kernel5-radius5/tumor/BraTS2021_00152/original_glcm_DifferenceEntropy.nrrd"
# Computed original_glcm_DifferenceVariance, stored as "./dataset/glcm/kernel5-radius5/tumor/BraTS2021_00152/original_glcm_DifferenceVariance.nrrd"
# Computed original_glcm_Id, stored as "./dataset/glcm/kernel5-radius5/tumor/BraTS2021_00152/original_glcm_Id.nrrd"
# Computed original_glcm_Idm, stored as "./dataset/glcm/kernel5-radius5/tumor/BraTS2021_00152/original_glcm_Idm.nrrd"
# Computed original_glcm_Idmn, stored as "./dataset/glcm/kernel5-radius5/tumor/BraTS2021_00152/original_glcm_Idmn.nrrd"
# Computed original_glcm_Idn, stored as "./dataset/glcm/kernel5-radius5/tumor/BraTS2021_00152/original_glcm_Idn.nrrd"
# Computed original_glcm_Imc1, stored as "./dataset/glcm/kernel5-radius5/tumor/BraTS2021_00152/original_glcm_Imc1.nrrd"
# Computed original_glcm_Imc2, stored as "./dataset/glcm/kernel5-radius5/tumor/BraTS2021_00152/original_glcm_Imc2.nrrd"
# Computed original_glcm_InverseVariance, stored as "./dataset/glcm/kernel5-radius5/tumor/BraTS2021_00152/original_glcm_InverseVariance.nrrd"
# Computed original_glcm_JointAverage, stored as "./dataset/glcm/kernel5-radius5/tumor/BraTS2021_00152/original_glcm_JointAverage.nrrd"
# Computed original_glcm_JointEnergy, stored as "./dataset/glcm/kernel5-radius5/tumor/BraTS2021_00152/original_glcm_JointEnergy.nrrd"
# Computed original_glcm_JointEntropy, stored as "./dataset/glcm/kernel5-radius5/tumor/BraTS2021_00152/original_glcm_JointEntropy.nrrd"
# Computed original_glcm_MCC, stored as "./dataset/glcm/kernel5-radius5/tumor/BraTS2021_00152/original_glcm_MCC.nrrd"
# Computed original_glcm_MaximumProbability, stored as "./dataset/glcm/kernel5-radius5/tumor/BraTS2021_00152/original_glcm_MaximumProbability.nrrd"
# Computed original_glcm_SumAverage, stored as "./dataset/glcm/kernel5-radius5/tumor/BraTS2021_00152/original_glcm_SumAverage.nrrd"
# Computed original_glcm_SumEntropy, stored as "./dataset/glcm/kernel5-radius5/tumor/BraTS2021_00152/original_glcm_SumEntropy.nrrd"
# Computed original_glcm_SumSquares, stored as "./dataset/glcm/kernel5-radius5/tumor/BraTS2021_00152/original_glcm_SumSquares.nrrd"
# Starting BraTS2021_00154
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# Computed original_glcm_Autocorrelation, stored as "./dataset/glcm/kernel5-radius5/tumor/BraTS2021_00154/original_glcm_Autocorrelation.nrrd"
# Computed original_glcm_ClusterProminence, stored as "./dataset/glcm/kernel5-radius5/tumor/BraTS2021_00154/original_glcm_ClusterProminence.nrrd"
# Computed original_glcm_ClusterShade, stored as "./dataset/glcm/kernel5-radius5/tumor/BraTS2021_00154/original_glcm_ClusterShade.nrrd"
# Computed original_glcm_ClusterTendency, stored as "./dataset/glcm/kernel5-radius5/tumor/BraTS2021_00154/original_glcm_ClusterTendency.nrrd"
# Computed original_glcm_Contrast, stored as "./dataset/glcm/kernel5-radius5/tumor/BraTS2021_00154/original_glcm_Contrast.nrrd"
# Computed original_glcm_Correlation, stored as "./dataset/glcm/kernel5-radius5/tumor/BraTS2021_00154/original_glcm_Correlation.nrrd"
# Computed original_glcm_DifferenceAverage, stored as "./dataset/glcm/kernel5-radius5/tumor/BraTS2021_00154/original_glcm_DifferenceAverage.nrrd"
# Computed original_glcm_DifferenceEntropy, stored as "./dataset/glcm/kernel5-radius5/tumor/BraTS2021_00154/original_glcm_DifferenceEntropy.nrrd"
# Computed original_glcm_DifferenceVariance, stored as "./dataset/glcm/kernel5-radius5/tumor/BraTS2021_00154/original_glcm_DifferenceVariance.nrrd"
# Computed original_glcm_Id, stored as "./dataset/glcm/kernel5-radius5/tumor/BraTS2021_00154/original_glcm_Id.nrrd"
# Computed original_glcm_Idm, stored as "./dataset/glcm/kernel5-radius5/tumor/BraTS2021_00154/original_glcm_Idm.nrrd"
# Computed original_glcm_Idmn, stored as "./dataset/glcm/kernel5-radius5/tumor/BraTS2021_00154/original_glcm_Idmn.nrrd"
# Computed original_glcm_Idn, stored as "./dataset/glcm/kernel5-radius5/tumor/BraTS2021_00154/original_glcm_Idn.nrrd"
# Computed original_glcm_Imc1, stored as "./dataset/glcm/kernel5-radius5/tumor/BraTS2021_00154/original_glcm_Imc1.nrrd"
# Computed original_glcm_Imc2, stored as "./dataset/glcm/kernel5-radius5/tumor/BraTS2021_00154/original_glcm_Imc2.nrrd"
# Computed original_glcm_InverseVariance, stored as "./dataset/glcm/kernel5-radius5/tumor/BraTS2021_00154/original_glcm_InverseVariance.nrrd"
# Computed original_glcm_JointAverage, stored as "./dataset/glcm/kernel5-radius5/tumor/BraTS2021_00154/original_glcm_JointAverage.nrrd"
# Computed original_glcm_JointEnergy, stored as "./dataset/glcm/kernel5-radius5/tumor/BraTS2021_00154/original_glcm_JointEnergy.nrrd"
# Computed original_glcm_JointEntropy, stored as "./dataset/glcm/kernel5-radius5/tumor/BraTS2021_00154/original_glcm_JointEntropy.nrrd"
# Computed original_glcm_MCC, stored as "./dataset/glcm/kernel5-radius5/tumor/BraTS2021_00154/original_glcm_MCC.nrrd"
# Computed original_glcm_MaximumProbability, stored as "./dataset/glcm/kernel5-radius5/tumor/BraTS2021_00154/original_glcm_MaximumProbability.nrrd"
# Computed original_glcm_SumAverage, stored as "./dataset/glcm/kernel5-radius5/tumor/BraTS2021_00154/original_glcm_SumAverage.nrrd"
# Computed original_glcm_SumEntropy, stored as "./dataset/glcm/kernel5-radius5/tumor/BraTS2021_00154/original_glcm_SumEntropy.nrrd"
# Computed original_glcm_SumSquares, stored as "./dataset/glcm/kernel5-radius5/tumor/BraTS2021_00154/original_glcm_SumSquares.nrrd"
# Starting BraTS2021_00155
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# Computed original_glcm_Autocorrelation, stored as "./dataset/glcm/kernel5-radius5/tumor/BraTS2021_00155/original_glcm_Autocorrelation.nrrd"
# Computed original_glcm_ClusterProminence, stored as "./dataset/glcm/kernel5-radius5/tumor/BraTS2021_00155/original_glcm_ClusterProminence.nrrd"
# Computed original_glcm_ClusterShade, stored as "./dataset/glcm/kernel5-radius5/tumor/BraTS2021_00155/original_glcm_ClusterShade.nrrd"
# Computed original_glcm_ClusterTendency, stored as "./dataset/glcm/kernel5-radius5/tumor/BraTS2021_00155/original_glcm_ClusterTendency.nrrd"
# Computed original_glcm_Contrast, stored as "./dataset/glcm/kernel5-radius5/tumor/BraTS2021_00155/original_glcm_Contrast.nrrd"
# Computed original_glcm_Correlation, stored as "./dataset/glcm/kernel5-radius5/tumor/BraTS2021_00155/original_glcm_Correlation.nrrd"
# Computed original_glcm_DifferenceAverage, stored as "./dataset/glcm/kernel5-radius5/tumor/BraTS2021_00155/original_glcm_DifferenceAverage.nrrd"
# Computed original_glcm_DifferenceEntropy, stored as "./dataset/glcm/kernel5-radius5/tumor/BraTS2021_00155/original_glcm_DifferenceEntropy.nrrd"
# Computed original_glcm_DifferenceVariance, stored as "./dataset/glcm/kernel5-radius5/tumor/BraTS2021_00155/original_glcm_DifferenceVariance.nrrd"
# Computed original_glcm_Id, stored as "./dataset/glcm/kernel5-radius5/tumor/BraTS2021_00155/original_glcm_Id.nrrd"
# Computed original_glcm_Idm, stored as "./dataset/glcm/kernel5-radius5/tumor/BraTS2021_00155/original_glcm_Idm.nrrd"
# Computed original_glcm_Idmn, stored as "./dataset/glcm/kernel5-radius5/tumor/BraTS2021_00155/original_glcm_Idmn.nrrd"
# Computed original_glcm_Idn, stored as "./dataset/glcm/kernel5-radius5/tumor/BraTS2021_00155/original_glcm_Idn.nrrd"
# Computed original_glcm_Imc1, stored as "./dataset/glcm/kernel5-radius5/tumor/BraTS2021_00155/original_glcm_Imc1.nrrd"
# Computed original_glcm_Imc2, stored as "./dataset/glcm/kernel5-radius5/tumor/BraTS2021_00155/original_glcm_Imc2.nrrd"
# Computed original_glcm_InverseVariance, stored as "./dataset/glcm/kernel5-radius5/tumor/BraTS2021_00155/original_glcm_InverseVariance.nrrd"
# Computed original_glcm_JointAverage, stored as "./dataset/glcm/kernel5-radius5/tumor/BraTS2021_00155/original_glcm_JointAverage.nrrd"
# Computed original_glcm_JointEnergy, stored as "./dataset/glcm/kernel5-radius5/tumor/BraTS2021_00155/original_glcm_JointEnergy.nrrd"
# Computed original_glcm_JointEntropy, stored as "./dataset/glcm/kernel5-radius5/tumor/BraTS2021_00155/original_glcm_JointEntropy.nrrd"
# Computed original_glcm_MCC, stored as "./dataset/glcm/kernel5-radius5/tumor/BraTS2021_00155/original_glcm_MCC.nrrd"
# Computed original_glcm_MaximumProbability, stored as "./dataset/glcm/kernel5-radius5/tumor/BraTS2021_00155/original_glcm_MaximumProbability.nrrd"
# Computed original_glcm_SumAverage, stored as "./dataset/glcm/kernel5-radius5/tumor/BraTS2021_00155/original_glcm_SumAverage.nrrd"
# Computed original_glcm_SumEntropy, stored as "./dataset/glcm/kernel5-radius5/tumor/BraTS2021_00155/original_glcm_SumEntropy.nrrd"
# Computed original_glcm_SumSquares, stored as "./dataset/glcm/kernel5-radius5/tumor/BraTS2021_00155/original_glcm_SumSquares.nrrd"
# Starting BraTS2021_00156
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# Computed original_glcm_Autocorrelation, stored as "./dataset/glcm/kernel5-radius5/tumor/BraTS2021_00156/original_glcm_Autocorrelation.nrrd"
# Computed original_glcm_ClusterProminence, stored as "./dataset/glcm/kernel5-radius5/tumor/BraTS2021_00156/original_glcm_ClusterProminence.nrrd"
# Computed original_glcm_ClusterShade, stored as "./dataset/glcm/kernel5-radius5/tumor/BraTS2021_00156/original_glcm_ClusterShade.nrrd"
# Computed original_glcm_ClusterTendency, stored as "./dataset/glcm/kernel5-radius5/tumor/BraTS2021_00156/original_glcm_ClusterTendency.nrrd"
# Computed original_glcm_Contrast, stored as "./dataset/glcm/kernel5-radius5/tumor/BraTS2021_00156/original_glcm_Contrast.nrrd"
# Computed original_glcm_Correlation, stored as "./dataset/glcm/kernel5-radius5/tumor/BraTS2021_00156/original_glcm_Correlation.nrrd"
# Computed original_glcm_DifferenceAverage, stored as "./dataset/glcm/kernel5-radius5/tumor/BraTS2021_00156/original_glcm_DifferenceAverage.nrrd"
# Computed original_glcm_DifferenceEntropy, stored as "./dataset/glcm/kernel5-radius5/tumor/BraTS2021_00156/original_glcm_DifferenceEntropy.nrrd"
# Computed original_glcm_DifferenceVariance, stored as "./dataset/glcm/kernel5-radius5/tumor/BraTS2021_00156/original_glcm_DifferenceVariance.nrrd"
# Computed original_glcm_Id, stored as "./dataset/glcm/kernel5-radius5/tumor/BraTS2021_00156/original_glcm_Id.nrrd"
# Computed original_glcm_Idm, stored as "./dataset/glcm/kernel5-radius5/tumor/BraTS2021_00156/original_glcm_Idm.nrrd"
# Computed original_glcm_Idmn, stored as "./dataset/glcm/kernel5-radius5/tumor/BraTS2021_00156/original_glcm_Idmn.nrrd"
# Computed original_glcm_Idn, stored as "./dataset/glcm/kernel5-radius5/tumor/BraTS2021_00156/original_glcm_Idn.nrrd"
# Computed original_glcm_Imc1, stored as "./dataset/glcm/kernel5-radius5/tumor/BraTS2021_00156/original_glcm_Imc1.nrrd"
# Computed original_glcm_Imc2, stored as "./dataset/glcm/kernel5-radius5/tumor/BraTS2021_00156/original_glcm_Imc2.nrrd"
# Computed original_glcm_InverseVariance, stored as "./dataset/glcm/kernel5-radius5/tumor/BraTS2021_00156/original_glcm_InverseVariance.nrrd"
# Computed original_glcm_JointAverage, stored as "./dataset/glcm/kernel5-radius5/tumor/BraTS2021_00156/original_glcm_JointAverage.nrrd"
# Computed original_glcm_JointEnergy, stored as "./dataset/glcm/kernel5-radius5/tumor/BraTS2021_00156/original_glcm_JointEnergy.nrrd"
# Computed original_glcm_JointEntropy, stored as "./dataset/glcm/kernel5-radius5/tumor/BraTS2021_00156/original_glcm_JointEntropy.nrrd"
# Computed original_glcm_MCC, stored as "./dataset/glcm/kernel5-radius5/tumor/BraTS2021_00156/original_glcm_MCC.nrrd"
# Computed original_glcm_MaximumProbability, stored as "./dataset/glcm/kernel5-radius5/tumor/BraTS2021_00156/original_glcm_MaximumProbability.nrrd"
# Computed original_glcm_SumAverage, stored as "./dataset/glcm/kernel5-radius5/tumor/BraTS2021_00156/original_glcm_SumAverage.nrrd"
# Computed original_glcm_SumEntropy, stored as "./dataset/glcm/kernel5-radius5/tumor/BraTS2021_00156/original_glcm_SumEntropy.nrrd"
# Computed original_glcm_SumSquares, stored as "./dataset/glcm/kernel5-radius5/tumor/BraTS2021_00156/original_glcm_SumSquares.nrrd"
# Starting BraTS2021_00157
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# Computed original_glcm_Autocorrelation, stored as "./dataset/glcm/kernel5-radius5/tumor/BraTS2021_00157/original_glcm_Autocorrelation.nrrd"
# Computed original_glcm_ClusterProminence, stored as "./dataset/glcm/kernel5-radius5/tumor/BraTS2021_00157/original_glcm_ClusterProminence.nrrd"
# Computed original_glcm_ClusterShade, stored as "./dataset/glcm/kernel5-radius5/tumor/BraTS2021_00157/original_glcm_ClusterShade.nrrd"
# Computed original_glcm_ClusterTendency, stored as "./dataset/glcm/kernel5-radius5/tumor/BraTS2021_00157/original_glcm_ClusterTendency.nrrd"
# Computed original_glcm_Contrast, stored as "./dataset/glcm/kernel5-radius5/tumor/BraTS2021_00157/original_glcm_Contrast.nrrd"
# Computed original_glcm_Correlation, stored as "./dataset/glcm/kernel5-radius5/tumor/BraTS2021_00157/original_glcm_Correlation.nrrd"
# Computed original_glcm_DifferenceAverage, stored as "./dataset/glcm/kernel5-radius5/tumor/BraTS2021_00157/original_glcm_DifferenceAverage.nrrd"
# Computed original_glcm_DifferenceEntropy, stored as "./dataset/glcm/kernel5-radius5/tumor/BraTS2021_00157/original_glcm_DifferenceEntropy.nrrd"
# Computed original_glcm_DifferenceVariance, stored as "./dataset/glcm/kernel5-radius5/tumor/BraTS2021_00157/original_glcm_DifferenceVariance.nrrd"
# Computed original_glcm_Id, stored as "./dataset/glcm/kernel5-radius5/tumor/BraTS2021_00157/original_glcm_Id.nrrd"
# Computed original_glcm_Idm, stored as "./dataset/glcm/kernel5-radius5/tumor/BraTS2021_00157/original_glcm_Idm.nrrd"
# Computed original_glcm_Idmn, stored as "./dataset/glcm/kernel5-radius5/tumor/BraTS2021_00157/original_glcm_Idmn.nrrd"
# Computed original_glcm_Idn, stored as "./dataset/glcm/kernel5-radius5/tumor/BraTS2021_00157/original_glcm_Idn.nrrd"
# Computed original_glcm_Imc1, stored as "./dataset/glcm/kernel5-radius5/tumor/BraTS2021_00157/original_glcm_Imc1.nrrd"
# Computed original_glcm_Imc2, stored as "./dataset/glcm/kernel5-radius5/tumor/BraTS2021_00157/original_glcm_Imc2.nrrd"
# Computed original_glcm_InverseVariance, stored as "./dataset/glcm/kernel5-radius5/tumor/BraTS2021_00157/original_glcm_InverseVariance.nrrd"
# Computed original_glcm_JointAverage, stored as "./dataset/glcm/kernel5-radius5/tumor/BraTS2021_00157/original_glcm_JointAverage.nrrd"
# ...
# Computed original_glcm_ClusterShade, stored as "./dataset/glcm/kernel5-radius5/tumor/BraTS2021_00281/original_glcm_ClusterShade.nrrd"
# Computed original_glcm_ClusterTendency, stored as "./dataset/glcm/kernel5-radius5/tumor/BraTS2021_00281/original_glcm_ClusterTendency.nrrd"
# Computed original_glcm_Contrast, stored as "./dataset/glcm/kernel5-radius5/tumor/BraTS2021_00281/original_glcm_Contrast.nrrd"
# Computed original_glcm_Correlation, stored as "./dataset/glcm/kernel5-radius5/tumor/BraTS2021_00281/original_glcm_Correlation.nrrd"
# Computed original_glcm_DifferenceAverage, stored as "./dataset/glcm/kernel5-radius5/tumor/BraTS2021_00281/original_glcm_DifferenceAverage.nrrd"
# Computed original_glcm_DifferenceEntropy, stored as "./dataset/glcm/kernel5-radius5/tumor/BraTS2021_00281/original_glcm_DifferenceEntropy.nrrd"
# Computed original_glcm_DifferenceVariance, stored as "./dataset/glcm/kernel5-radius5/tumor/BraTS2021_00281/original_glcm_DifferenceVariance.nrrd"
# Computed original_glcm_Id, stored as "./dataset/glcm/kernel5-radius5/tumor/BraTS2021_00281/original_glcm_Id.nrrd"
# Computed original_glcm_Idm, stored as "./dataset/glcm/kernel5-radius5/tumor/BraTS2021_00281/original_glcm_Idm.nrrd"
# Computed original_glcm_Idmn, stored as "./dataset/glcm/kernel5-radius5/tumor/BraTS2021_00281/original_glcm_Idmn.nrrd"
# Computed original_glcm_Idn, stored as "./dataset/glcm/kernel5-radius5/tumor/BraTS2021_00281/original_glcm_Idn.nrrd"
# Computed original_glcm_Imc1, stored as "./dataset/glcm/kernel5-radius5/tumor/BraTS2021_00281/original_glcm_Imc1.nrrd"
# Computed original_glcm_Imc2, stored as "./dataset/glcm/kernel5-radius5/tumor/BraTS2021_00281/original_glcm_Imc2.nrrd"
# Computed original_glcm_InverseVariance, stored as "./dataset/glcm/kernel5-radius5/tumor/BraTS2021_00281/original_glcm_InverseVariance.nrrd"
# Computed original_glcm_JointAverage, stored as "./dataset/glcm/kernel5-radius5/tumor/BraTS2021_00281/original_glcm_JointAverage.nrrd"
# Computed original_glcm_JointEnergy, stored as "./dataset/glcm/kernel5-radius5/tumor/BraTS2021_00281/original_glcm_JointEnergy.nrrd"
# Computed original_glcm_JointEntropy, stored as "./dataset/glcm/kernel5-radius5/tumor/BraTS2021_00281/original_glcm_JointEntropy.nrrd"
# Computed original_glcm_MCC, stored as "./dataset/glcm/kernel5-radius5/tumor/BraTS2021_00281/original_glcm_MCC.nrrd"
# Computed original_glcm_MaximumProbability, stored as "./dataset/glcm/kernel5-radius5/tumor/BraTS2021_00281/original_glcm_MaximumProbability.nrrd"
# Computed original_glcm_SumAverage, stored as "./dataset/glcm/kernel5-radius5/tumor/BraTS2021_00281/original_glcm_SumAverage.nrrd"
# Computed original_glcm_SumEntropy, stored as "./dataset/glcm/kernel5-radius5/tumor/BraTS2021_00281/original_glcm_SumEntropy.nrrd"
# Computed original_glcm_SumSquares, stored as "./dataset/glcm/kernel5-radius5/tumor/BraTS2021_00281/original_glcm_SumSquares.nrrd"
# Starting BraTS2021_00282
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# Computed original_glcm_Autocorrelation, stored as "./dataset/glcm/kernel5-radius5/tumor/BraTS2021_00282/original_glcm_Autocorrelation.nrrd"
# Computed original_glcm_ClusterProminence, stored as "./dataset/glcm/kernel5-radius5/tumor/BraTS2021_00282/original_glcm_ClusterProminence.nrrd"
# Computed original_glcm_ClusterShade, stored as "./dataset/glcm/kernel5-radius5/tumor/BraTS2021_00282/original_glcm_ClusterShade.nrrd"
# Computed original_glcm_ClusterTendency, stored as "./dataset/glcm/kernel5-radius5/tumor/BraTS2021_00282/original_glcm_ClusterTendency.nrrd"
# Computed original_glcm_Contrast, stored as "./dataset/glcm/kernel5-radius5/tumor/BraTS2021_00282/original_glcm_Contrast.nrrd"
# Computed original_glcm_Correlation, stored as "./dataset/glcm/kernel5-radius5/tumor/BraTS2021_00282/original_glcm_Correlation.nrrd"
# Computed original_glcm_DifferenceAverage, stored as "./dataset/glcm/kernel5-radius5/tumor/BraTS2021_00282/original_glcm_DifferenceAverage.nrrd"
# Computed original_glcm_DifferenceEntropy, stored as "./dataset/glcm/kernel5-radius5/tumor/BraTS2021_00282/original_glcm_DifferenceEntropy.nrrd"
# Computed original_glcm_DifferenceVariance, stored as "./dataset/glcm/kernel5-radius5/tumor/BraTS2021_00282/original_glcm_DifferenceVariance.nrrd"
# Computed original_glcm_Id, stored as "./dataset/glcm/kernel5-radius5/tumor/BraTS2021_00282/original_glcm_Id.nrrd"
# Computed original_glcm_Idm, stored as "./dataset/glcm/kernel5-radius5/tumor/BraTS2021_00282/original_glcm_Idm.nrrd"
# Computed original_glcm_Idmn, stored as "./dataset/glcm/kernel5-radius5/tumor/BraTS2021_00282/original_glcm_Idmn.nrrd"
# Computed original_glcm_Idn, stored as "./dataset/glcm/kernel5-radius5/tumor/BraTS2021_00282/original_glcm_Idn.nrrd"
# Computed original_glcm_Imc1, stored as "./dataset/glcm/kernel5-radius5/tumor/BraTS2021_00282/original_glcm_Imc1.nrrd"
# Computed original_glcm_Imc2, stored as "./dataset/glcm/kernel5-radius5/tumor/BraTS2021_00282/original_glcm_Imc2.nrrd"
# Computed original_glcm_InverseVariance, stored as "./dataset/glcm/kernel5-radius5/tumor/BraTS2021_00282/original_glcm_InverseVariance.nrrd"
# Computed original_glcm_JointAverage, stored as "./dataset/glcm/kernel5-radius5/tumor/BraTS2021_00282/original_glcm_JointAverage.nrrd"
# Computed original_glcm_JointEnergy, stored as "./dataset/glcm/kernel5-radius5/tumor/BraTS2021_00282/original_glcm_JointEnergy.nrrd"
# Computed original_glcm_JointEntropy, stored as "./dataset/glcm/kernel5-radius5/tumor/BraTS2021_00282/original_glcm_JointEntropy.nrrd"
# Computed original_glcm_MCC, stored as "./dataset/glcm/kernel5-radius5/tumor/BraTS2021_00282/original_glcm_MCC.nrrd"
# Computed original_glcm_MaximumProbability, stored as "./dataset/glcm/kernel5-radius5/tumor/BraTS2021_00282/original_glcm_MaximumProbability.nrrd"
# Computed original_glcm_SumAverage, stored as "./dataset/glcm/kernel5-radius5/tumor/BraTS2021_00282/original_glcm_SumAverage.nrrd"
# Computed original_glcm_SumEntropy, stored as "./dataset/glcm/kernel5-radius5/tumor/BraTS2021_00282/original_glcm_SumEntropy.nrrd"
# Computed original_glcm_SumSquares, stored as "./dataset/glcm/kernel5-radius5/tumor/BraTS2021_00282/original_glcm_SumSquares.nrrd"
# Starting BraTS2021_00283
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# Computed original_glcm_Autocorrelation, stored as "./dataset/glcm/kernel5-radius5/tumor/BraTS2021_00283/original_glcm_Autocorrelation.nrrd"
# Computed original_glcm_ClusterProminence, stored as "./dataset/glcm/kernel5-radius5/tumor/BraTS2021_00283/original_glcm_ClusterProminence.nrrd"
# Computed original_glcm_ClusterShade, stored as "./dataset/glcm/kernel5-radius5/tumor/BraTS2021_00283/original_glcm_ClusterShade.nrrd"
# Computed original_glcm_ClusterTendency, stored as "./dataset/glcm/kernel5-radius5/tumor/BraTS2021_00283/original_glcm_ClusterTendency.nrrd"
# Computed original_glcm_Contrast, stored as "./dataset/glcm/kernel5-radius5/tumor/BraTS2021_00283/original_glcm_Contrast.nrrd"
# Computed original_glcm_Correlation, stored as "./dataset/glcm/kernel5-radius5/tumor/BraTS2021_00283/original_glcm_Correlation.nrrd"
# Computed original_glcm_DifferenceAverage, stored as "./dataset/glcm/kernel5-radius5/tumor/BraTS2021_00283/original_glcm_DifferenceAverage.nrrd"
# Computed original_glcm_DifferenceEntropy, stored as "./dataset/glcm/kernel5-radius5/tumor/BraTS2021_00283/original_glcm_DifferenceEntropy.nrrd"
# Computed original_glcm_DifferenceVariance, stored as "./dataset/glcm/kernel5-radius5/tumor/BraTS2021_00283/original_glcm_DifferenceVariance.nrrd"
# Computed original_glcm_Id, stored as "./dataset/glcm/kernel5-radius5/tumor/BraTS2021_00283/original_glcm_Id.nrrd"
# Computed original_glcm_Idm, stored as "./dataset/glcm/kernel5-radius5/tumor/BraTS2021_00283/original_glcm_Idm.nrrd"
# Computed original_glcm_Idmn, stored as "./dataset/glcm/kernel5-radius5/tumor/BraTS2021_00283/original_glcm_Idmn.nrrd"
# Computed original_glcm_Idn, stored as "./dataset/glcm/kernel5-radius5/tumor/BraTS2021_00283/original_glcm_Idn.nrrd"
# Computed original_glcm_Imc1, stored as "./dataset/glcm/kernel5-radius5/tumor/BraTS2021_00283/original_glcm_Imc1.nrrd"
# Computed original_glcm_Imc2, stored as "./dataset/glcm/kernel5-radius5/tumor/BraTS2021_00283/original_glcm_Imc2.nrrd"
# Computed original_glcm_InverseVariance, stored as "./dataset/glcm/kernel5-radius5/tumor/BraTS2021_00283/original_glcm_InverseVariance.nrrd"
# Computed original_glcm_JointAverage, stored as "./dataset/glcm/kernel5-radius5/tumor/BraTS2021_00283/original_glcm_JointAverage.nrrd"
# Computed original_glcm_JointEnergy, stored as "./dataset/glcm/kernel5-radius5/tumor/BraTS2021_00283/original_glcm_JointEnergy.nrrd"
# Computed original_glcm_JointEntropy, stored as "./dataset/glcm/kernel5-radius5/tumor/BraTS2021_00283/original_glcm_JointEntropy.nrrd"
# Computed original_glcm_MCC, stored as "./dataset/glcm/kernel5-radius5/tumor/BraTS2021_00283/original_glcm_MCC.nrrd"
# Computed original_glcm_MaximumProbability, stored as "./dataset/glcm/kernel5-radius5/tumor/BraTS2021_00283/original_glcm_MaximumProbability.nrrd"
# Computed original_glcm_SumAverage, stored as "./dataset/glcm/kernel5-radius5/tumor/BraTS2021_00283/original_glcm_SumAverage.nrrd"
# Computed original_glcm_SumEntropy, stored as "./dataset/glcm/kernel5-radius5/tumor/BraTS2021_00283/original_glcm_SumEntropy.nrrd"
# Computed original_glcm_SumSquares, stored as "./dataset/glcm/kernel5-radius5/tumor/BraTS2021_00283/original_glcm_SumSquares.nrrd"
# Starting BraTS2021_00284
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# Computed original_glcm_Autocorrelation, stored as "./dataset/glcm/kernel5-radius5/tumor/BraTS2021_00284/original_glcm_Autocorrelation.nrrd"
# Computed original_glcm_ClusterProminence, stored as "./dataset/glcm/kernel5-radius5/tumor/BraTS2021_00284/original_glcm_ClusterProminence.nrrd"
# Computed original_glcm_ClusterShade, stored as "./dataset/glcm/kernel5-radius5/tumor/BraTS2021_00284/original_glcm_ClusterShade.nrrd"
# Computed original_glcm_ClusterTendency, stored as "./dataset/glcm/kernel5-radius5/tumor/BraTS2021_00284/original_glcm_ClusterTendency.nrrd"
# Computed original_glcm_Contrast, stored as "./dataset/glcm/kernel5-radius5/tumor/BraTS2021_00284/original_glcm_Contrast.nrrd"
# Computed original_glcm_Correlation, stored as "./dataset/glcm/kernel5-radius5/tumor/BraTS2021_00284/original_glcm_Correlation.nrrd"
# Computed original_glcm_DifferenceAverage, stored as "./dataset/glcm/kernel5-radius5/tumor/BraTS2021_00284/original_glcm_DifferenceAverage.nrrd"
# Computed original_glcm_DifferenceEntropy, stored as "./dataset/glcm/kernel5-radius5/tumor/BraTS2021_00284/original_glcm_DifferenceEntropy.nrrd"
# Computed original_glcm_DifferenceVariance, stored as "./dataset/glcm/kernel5-radius5/tumor/BraTS2021_00284/original_glcm_DifferenceVariance.nrrd"
# Computed original_glcm_Id, stored as "./dataset/glcm/kernel5-radius5/tumor/BraTS2021_00284/original_glcm_Id.nrrd"
# Computed original_glcm_Idm, stored as "./dataset/glcm/kernel5-radius5/tumor/BraTS2021_00284/original_glcm_Idm.nrrd"
# Computed original_glcm_Idmn, stored as "./dataset/glcm/kernel5-radius5/tumor/BraTS2021_00284/original_glcm_Idmn.nrrd"
# Computed original_glcm_Idn, stored as "./dataset/glcm/kernel5-radius5/tumor/BraTS2021_00284/original_glcm_Idn.nrrd"
# Computed original_glcm_Imc1, stored as "./dataset/glcm/kernel5-radius5/tumor/BraTS2021_00284/original_glcm_Imc1.nrrd"
# Computed original_glcm_Imc2, stored as "./dataset/glcm/kernel5-radius5/tumor/BraTS2021_00284/original_glcm_Imc2.nrrd"
# Computed original_glcm_InverseVariance, stored as "./dataset/glcm/kernel5-radius5/tumor/BraTS2021_00284/original_glcm_InverseVariance.nrrd"
# Computed original_glcm_JointAverage, stored as "./dataset/glcm/kernel5-radius5/tumor/BraTS2021_00284/original_glcm_JointAverage.nrrd"
# Computed original_glcm_JointEnergy, stored as "./dataset/glcm/kernel5-radius5/tumor/BraTS2021_00284/original_glcm_JointEnergy.nrrd"
# Computed original_glcm_JointEntropy, stored as "./dataset/glcm/kernel5-radius5/tumor/BraTS2021_00284/original_glcm_JointEntropy.nrrd"
# Computed original_glcm_MCC, stored as "./dataset/glcm/kernel5-radius5/tumor/BraTS2021_00284/original_glcm_MCC.nrrd"
# Computed original_glcm_MaximumProbability, stored as "./dataset/glcm/kernel5-radius5/tumor/BraTS2021_00284/original_glcm_MaximumProbability.nrrd"
# Computed original_glcm_SumAverage, stored as "./dataset/glcm/kernel5-radius5/tumor/BraTS2021_00284/original_glcm_SumAverage.nrrd"
# Computed original_glcm_SumEntropy, stored as "./dataset/glcm/kernel5-radius5/tumor/BraTS2021_00284/original_glcm_SumEntropy.nrrd"
# Computed original_glcm_SumSquares, stored as "./dataset/glcm/kernel5-radius5/tumor/BraTS2021_00284/original_glcm_SumSquares.nrrd"
# Starting BraTS2021_00285
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# Computed original_glcm_Autocorrelation, stored as "./dataset/glcm/kernel5-radius5/tumor/BraTS2021_00285/original_glcm_Autocorrelation.nrrd"
# Computed original_glcm_ClusterProminence, stored as "./dataset/glcm/kernel5-radius5/tumor/BraTS2021_00285/original_glcm_ClusterProminence.nrrd"
# Computed original_glcm_ClusterShade, stored as "./dataset/glcm/kernel5-radius5/tumor/BraTS2021_00285/original_glcm_ClusterShade.nrrd"
# Computed original_glcm_ClusterTendency, stored as "./dataset/glcm/kernel5-radius5/tumor/BraTS2021_00285/original_glcm_ClusterTendency.nrrd"
# Computed original_glcm_Contrast, stored as "./dataset/glcm/kernel5-radius5/tumor/BraTS2021_00285/original_glcm_Contrast.nrrd"
# Computed original_glcm_Correlation, stored as "./dataset/glcm/kernel5-radius5/tumor/BraTS2021_00285/original_glcm_Correlation.nrrd"
# Computed original_glcm_DifferenceAverage, stored as "./dataset/glcm/kernel5-radius5/tumor/BraTS2021_00285/original_glcm_DifferenceAverage.nrrd"
# Computed original_glcm_DifferenceEntropy, stored as "./dataset/glcm/kernel5-radius5/tumor/BraTS2021_00285/original_glcm_DifferenceEntropy.nrrd"
# Computed original_glcm_DifferenceVariance, stored as "./dataset/glcm/kernel5-radius5/tumor/BraTS2021_00285/original_glcm_DifferenceVariance.nrrd"
# Computed original_glcm_Id, stored as "./dataset/glcm/kernel5-radius5/tumor/BraTS2021_00285/original_glcm_Id.nrrd"
# Computed original_glcm_Idm, stored as "./dataset/glcm/kernel5-radius5/tumor/BraTS2021_00285/original_glcm_Idm.nrrd"
# Computed original_glcm_Idmn, stored as "./dataset/glcm/kernel5-radius5/tumor/BraTS2021_00285/original_glcm_Idmn.nrrd"
# Computed original_glcm_Idn, stored as "./dataset/glcm/kernel5-radius5/tumor/BraTS2021_00285/original_glcm_Idn.nrrd"
# Computed original_glcm_Imc1, stored as "./dataset/glcm/kernel5-radius5/tumor/BraTS2021_00285/original_glcm_Imc1.nrrd"
# Computed original_glcm_Imc2, stored as "./dataset/glcm/kernel5-radius5/tumor/BraTS2021_00285/original_glcm_Imc2.nrrd"
# Computed original_glcm_InverseVariance, stored as "./dataset/glcm/kernel5-radius5/tumor/BraTS2021_00285/original_glcm_InverseVariance.nrrd"
# Computed original_glcm_JointAverage, stored as "./dataset/glcm/kernel5-radius5/tumor/BraTS2021_00285/original_glcm_JointAverage.nrrd"
# Computed original_glcm_JointEnergy, stored as "./dataset/glcm/kernel5-radius5/tumor/BraTS2021_00285/original_glcm_JointEnergy.nrrd"
# Computed original_glcm_JointEntropy, stored as "./dataset/glcm/kernel5-radius5/tumor/BraTS2021_00285/original_glcm_JointEntropy.nrrd"
# Computed original_glcm_MCC, stored as "./dataset/glcm/kernel5-radius5/tumor/BraTS2021_00285/original_glcm_MCC.nrrd"
# Computed original_glcm_MaximumProbability, stored as "./dataset/glcm/kernel5-radius5/tumor/BraTS2021_00285/original_glcm_MaximumProbability.nrrd"
# Computed original_glcm_SumAverage, stored as "./dataset/glcm/kernel5-radius5/tumor/BraTS2021_00285/original_glcm_SumAverage.nrrd"
# Computed original_glcm_SumEntropy, stored as "./dataset/glcm/kernel5-radius5/tumor/BraTS2021_00285/original_glcm_SumEntropy.nrrd"
# Computed original_glcm_SumSquares, stored as "./dataset/glcm/kernel5-radius5/tumor/BraTS2021_00285/original_glcm_SumSquares.nrrd"
