# %% [markdown]
# <a href="https://colab.research.google.com/github/ntatfff/todo/blob/202411241258/ColabRadiomicsFeatureExtractor.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import radiomics
import numpy as np
import SimpleITK as sitk
import radiomics.featureextractor
import os
import six
from os import path
import pandas as pd

def featureExtractor(fileId):
  imagePath = './dataset/BraTS2021_Training_Data/%s/%s_flair.nii.gz' % (fileId, fileId)
  image = sitk.ReadImage(imagePath)
  maskPath ='./dataset/BraTS2021_Training_Data/%s/%s_kernel5_tumor.nii.gz' % (fileId, fileId)
  mask = sitk.ReadImage(maskPath)

  kernel = 5
  settings = {}
  settings['kernelRadius'] = kernel
  settings['maskedKernel'] = False
  settings['voxelBatch'] = 40000
  extractor = radiomics.featureextractor.RadiomicsFeatureExtractor(**settings)
  extractor.disableAllFeatures()
  extractor.enableFeatureClassByName('glcm')

  featureMap = extractor.execute(image, mask, voxelBased=True)

  for featureName, featureValue in six.iteritems(featureMap):
    if isinstance(featureValue, sitk.Image):
      fileFolder = './dataset/glcm/kernel5/tumor/%s' % (fileId)
      if path.exists(fileFolder) == False:
        os.mkdir(fileFolder)
      sitk.WriteImage(featureValue, '%s/%s.nrrd' % (fileFolder, featureName))
      print('Computed %s, stored as "%s/%s.nrrd"' % (featureName, fileFolder, featureName))
    # else:
    #   print('%s: %s' % (featureName, featureValue))

monitorFilePath = './dataset/glcm/kernel5/tumor.monitor.csv'
monitor = pd.read_csv(monitorFilePath, index_col='no')
for i, row in monitor.iterrows():
  if row['done'] != 0:
    continue
  fileId = row['file']
  print('Starting %s' % (fileId))
  featureExtractor(fileId)
  monitor.at[i, 'done'] = 1
  monitor.to_csv(monitorFilePath)
# Out:
# Starting BraTS2021_00286
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# Computed original_glcm_Autocorrelation, stored as "./dataset/glcm/kernel5/tumor/BraTS2021_00286/original_glcm_Autocorrelation.nrrd"
# Computed original_glcm_ClusterProminence, stored as "./dataset/glcm/kernel5/tumor/BraTS2021_00286/original_glcm_ClusterProminence.nrrd"
# Computed original_glcm_ClusterShade, stored as "./dataset/glcm/kernel5/tumor/BraTS2021_00286/original_glcm_ClusterShade.nrrd"
# Computed original_glcm_ClusterTendency, stored as "./dataset/glcm/kernel5/tumor/BraTS2021_00286/original_glcm_ClusterTendency.nrrd"
# Computed original_glcm_Contrast, stored as "./dataset/glcm/kernel5/tumor/BraTS2021_00286/original_glcm_Contrast.nrrd"
# Computed original_glcm_Correlation, stored as "./dataset/glcm/kernel5/tumor/BraTS2021_00286/original_glcm_Correlation.nrrd"
# Computed original_glcm_DifferenceAverage, stored as "./dataset/glcm/kernel5/tumor/BraTS2021_00286/original_glcm_DifferenceAverage.nrrd"
# Computed original_glcm_DifferenceEntropy, stored as "./dataset/glcm/kernel5/tumor/BraTS2021_00286/original_glcm_DifferenceEntropy.nrrd"
# Computed original_glcm_DifferenceVariance, stored as "./dataset/glcm/kernel5/tumor/BraTS2021_00286/original_glcm_DifferenceVariance.nrrd"
# Computed original_glcm_Id, stored as "./dataset/glcm/kernel5/tumor/BraTS2021_00286/original_glcm_Id.nrrd"
# Computed original_glcm_Idm, stored as "./dataset/glcm/kernel5/tumor/BraTS2021_00286/original_glcm_Idm.nrrd"
# Computed original_glcm_Idmn, stored as "./dataset/glcm/kernel5/tumor/BraTS2021_00286/original_glcm_Idmn.nrrd"
# Computed original_glcm_Idn, stored as "./dataset/glcm/kernel5/tumor/BraTS2021_00286/original_glcm_Idn.nrrd"
# Computed original_glcm_Imc1, stored as "./dataset/glcm/kernel5/tumor/BraTS2021_00286/original_glcm_Imc1.nrrd"
# Computed original_glcm_Imc2, stored as "./dataset/glcm/kernel5/tumor/BraTS2021_00286/original_glcm_Imc2.nrrd"
# Computed original_glcm_InverseVariance, stored as "./dataset/glcm/kernel5/tumor/BraTS2021_00286/original_glcm_InverseVariance.nrrd"
# Computed original_glcm_JointAverage, stored as "./dataset/glcm/kernel5/tumor/BraTS2021_00286/original_glcm_JointAverage.nrrd"
# Computed original_glcm_JointEnergy, stored as "./dataset/glcm/kernel5/tumor/BraTS2021_00286/original_glcm_JointEnergy.nrrd"
# Computed original_glcm_JointEntropy, stored as "./dataset/glcm/kernel5/tumor/BraTS2021_00286/original_glcm_JointEntropy.nrrd"
# Computed original_glcm_MCC, stored as "./dataset/glcm/kernel5/tumor/BraTS2021_00286/original_glcm_MCC.nrrd"
# Computed original_glcm_MaximumProbability, stored as "./dataset/glcm/kernel5/tumor/BraTS2021_00286/original_glcm_MaximumProbability.nrrd"
# Computed original_glcm_SumAverage, stored as "./dataset/glcm/kernel5/tumor/BraTS2021_00286/original_glcm_SumAverage.nrrd"
# Computed original_glcm_SumEntropy, stored as "./dataset/glcm/kernel5/tumor/BraTS2021_00286/original_glcm_SumEntropy.nrrd"
# Computed original_glcm_SumSquares, stored as "./dataset/glcm/kernel5/tumor/BraTS2021_00286/original_glcm_SumSquares.nrrd"
# Starting BraTS2021_00288
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# Computed original_glcm_Autocorrelation, stored as "./dataset/glcm/kernel5/tumor/BraTS2021_00288/original_glcm_Autocorrelation.nrrd"
# Computed original_glcm_ClusterProminence, stored as "./dataset/glcm/kernel5/tumor/BraTS2021_00288/original_glcm_ClusterProminence.nrrd"
# Computed original_glcm_ClusterShade, stored as "./dataset/glcm/kernel5/tumor/BraTS2021_00288/original_glcm_ClusterShade.nrrd"
# Computed original_glcm_ClusterTendency, stored as "./dataset/glcm/kernel5/tumor/BraTS2021_00288/original_glcm_ClusterTendency.nrrd"
# Computed original_glcm_Contrast, stored as "./dataset/glcm/kernel5/tumor/BraTS2021_00288/original_glcm_Contrast.nrrd"
# Computed original_glcm_Correlation, stored as "./dataset/glcm/kernel5/tumor/BraTS2021_00288/original_glcm_Correlation.nrrd"
# Computed original_glcm_DifferenceAverage, stored as "./dataset/glcm/kernel5/tumor/BraTS2021_00288/original_glcm_DifferenceAverage.nrrd"
# Computed original_glcm_DifferenceEntropy, stored as "./dataset/glcm/kernel5/tumor/BraTS2021_00288/original_glcm_DifferenceEntropy.nrrd"
# Computed original_glcm_DifferenceVariance, stored as "./dataset/glcm/kernel5/tumor/BraTS2021_00288/original_glcm_DifferenceVariance.nrrd"
# Computed original_glcm_Id, stored as "./dataset/glcm/kernel5/tumor/BraTS2021_00288/original_glcm_Id.nrrd"
# Computed original_glcm_Idm, stored as "./dataset/glcm/kernel5/tumor/BraTS2021_00288/original_glcm_Idm.nrrd"
# Computed original_glcm_Idmn, stored as "./dataset/glcm/kernel5/tumor/BraTS2021_00288/original_glcm_Idmn.nrrd"
# Computed original_glcm_Idn, stored as "./dataset/glcm/kernel5/tumor/BraTS2021_00288/original_glcm_Idn.nrrd"
# Computed original_glcm_Imc1, stored as "./dataset/glcm/kernel5/tumor/BraTS2021_00288/original_glcm_Imc1.nrrd"
# Computed original_glcm_Imc2, stored as "./dataset/glcm/kernel5/tumor/BraTS2021_00288/original_glcm_Imc2.nrrd"
# Computed original_glcm_InverseVariance, stored as "./dataset/glcm/kernel5/tumor/BraTS2021_00288/original_glcm_InverseVariance.nrrd"
# Computed original_glcm_JointAverage, stored as "./dataset/glcm/kernel5/tumor/BraTS2021_00288/original_glcm_JointAverage.nrrd"
# Computed original_glcm_JointEnergy, stored as "./dataset/glcm/kernel5/tumor/BraTS2021_00288/original_glcm_JointEnergy.nrrd"
# Computed original_glcm_JointEntropy, stored as "./dataset/glcm/kernel5/tumor/BraTS2021_00288/original_glcm_JointEntropy.nrrd"
# Computed original_glcm_MCC, stored as "./dataset/glcm/kernel5/tumor/BraTS2021_00288/original_glcm_MCC.nrrd"
# Computed original_glcm_MaximumProbability, stored as "./dataset/glcm/kernel5/tumor/BraTS2021_00288/original_glcm_MaximumProbability.nrrd"
# Computed original_glcm_SumAverage, stored as "./dataset/glcm/kernel5/tumor/BraTS2021_00288/original_glcm_SumAverage.nrrd"
# Computed original_glcm_SumEntropy, stored as "./dataset/glcm/kernel5/tumor/BraTS2021_00288/original_glcm_SumEntropy.nrrd"
# Computed original_glcm_SumSquares, stored as "./dataset/glcm/kernel5/tumor/BraTS2021_00288/original_glcm_SumSquares.nrrd"
# Starting BraTS2021_00289
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# Computed original_glcm_Autocorrelation, stored as "./dataset/glcm/kernel5/tumor/BraTS2021_00289/original_glcm_Autocorrelation.nrrd"
# Computed original_glcm_ClusterProminence, stored as "./dataset/glcm/kernel5/tumor/BraTS2021_00289/original_glcm_ClusterProminence.nrrd"
# Computed original_glcm_ClusterShade, stored as "./dataset/glcm/kernel5/tumor/BraTS2021_00289/original_glcm_ClusterShade.nrrd"
# Computed original_glcm_ClusterTendency, stored as "./dataset/glcm/kernel5/tumor/BraTS2021_00289/original_glcm_ClusterTendency.nrrd"
# Computed original_glcm_Contrast, stored as "./dataset/glcm/kernel5/tumor/BraTS2021_00289/original_glcm_Contrast.nrrd"
# Computed original_glcm_Correlation, stored as "./dataset/glcm/kernel5/tumor/BraTS2021_00289/original_glcm_Correlation.nrrd"
# Computed original_glcm_DifferenceAverage, stored as "./dataset/glcm/kernel5/tumor/BraTS2021_00289/original_glcm_DifferenceAverage.nrrd"
# Computed original_glcm_DifferenceEntropy, stored as "./dataset/glcm/kernel5/tumor/BraTS2021_00289/original_glcm_DifferenceEntropy.nrrd"
# Computed original_glcm_DifferenceVariance, stored as "./dataset/glcm/kernel5/tumor/BraTS2021_00289/original_glcm_DifferenceVariance.nrrd"
# Computed original_glcm_Id, stored as "./dataset/glcm/kernel5/tumor/BraTS2021_00289/original_glcm_Id.nrrd"
# Computed original_glcm_Idm, stored as "./dataset/glcm/kernel5/tumor/BraTS2021_00289/original_glcm_Idm.nrrd"
# Computed original_glcm_Idmn, stored as "./dataset/glcm/kernel5/tumor/BraTS2021_00289/original_glcm_Idmn.nrrd"
# Computed original_glcm_Idn, stored as "./dataset/glcm/kernel5/tumor/BraTS2021_00289/original_glcm_Idn.nrrd"
# Computed original_glcm_Imc1, stored as "./dataset/glcm/kernel5/tumor/BraTS2021_00289/original_glcm_Imc1.nrrd"
# Computed original_glcm_Imc2, stored as "./dataset/glcm/kernel5/tumor/BraTS2021_00289/original_glcm_Imc2.nrrd"
# Computed original_glcm_InverseVariance, stored as "./dataset/glcm/kernel5/tumor/BraTS2021_00289/original_glcm_InverseVariance.nrrd"
# Computed original_glcm_JointAverage, stored as "./dataset/glcm/kernel5/tumor/BraTS2021_00289/original_glcm_JointAverage.nrrd"
# Computed original_glcm_JointEnergy, stored as "./dataset/glcm/kernel5/tumor/BraTS2021_00289/original_glcm_JointEnergy.nrrd"
# Computed original_glcm_JointEntropy, stored as "./dataset/glcm/kernel5/tumor/BraTS2021_00289/original_glcm_JointEntropy.nrrd"
# Computed original_glcm_MCC, stored as "./dataset/glcm/kernel5/tumor/BraTS2021_00289/original_glcm_MCC.nrrd"
# Computed original_glcm_MaximumProbability, stored as "./dataset/glcm/kernel5/tumor/BraTS2021_00289/original_glcm_MaximumProbability.nrrd"
# Computed original_glcm_SumAverage, stored as "./dataset/glcm/kernel5/tumor/BraTS2021_00289/original_glcm_SumAverage.nrrd"
# Computed original_glcm_SumEntropy, stored as "./dataset/glcm/kernel5/tumor/BraTS2021_00289/original_glcm_SumEntropy.nrrd"
# Computed original_glcm_SumSquares, stored as "./dataset/glcm/kernel5/tumor/BraTS2021_00289/original_glcm_SumSquares.nrrd"
# Starting BraTS2021_00290
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# Computed original_glcm_Autocorrelation, stored as "./dataset/glcm/kernel5/tumor/BraTS2021_00290/original_glcm_Autocorrelation.nrrd"
# Computed original_glcm_ClusterProminence, stored as "./dataset/glcm/kernel5/tumor/BraTS2021_00290/original_glcm_ClusterProminence.nrrd"
# Computed original_glcm_ClusterShade, stored as "./dataset/glcm/kernel5/tumor/BraTS2021_00290/original_glcm_ClusterShade.nrrd"
# Computed original_glcm_ClusterTendency, stored as "./dataset/glcm/kernel5/tumor/BraTS2021_00290/original_glcm_ClusterTendency.nrrd"
# Computed original_glcm_Contrast, stored as "./dataset/glcm/kernel5/tumor/BraTS2021_00290/original_glcm_Contrast.nrrd"
# Computed original_glcm_Correlation, stored as "./dataset/glcm/kernel5/tumor/BraTS2021_00290/original_glcm_Correlation.nrrd"
# Computed original_glcm_DifferenceAverage, stored as "./dataset/glcm/kernel5/tumor/BraTS2021_00290/original_glcm_DifferenceAverage.nrrd"
# Computed original_glcm_DifferenceEntropy, stored as "./dataset/glcm/kernel5/tumor/BraTS2021_00290/original_glcm_DifferenceEntropy.nrrd"
# Computed original_glcm_DifferenceVariance, stored as "./dataset/glcm/kernel5/tumor/BraTS2021_00290/original_glcm_DifferenceVariance.nrrd"
# Computed original_glcm_Id, stored as "./dataset/glcm/kernel5/tumor/BraTS2021_00290/original_glcm_Id.nrrd"
# Computed original_glcm_Idm, stored as "./dataset/glcm/kernel5/tumor/BraTS2021_00290/original_glcm_Idm.nrrd"
# Computed original_glcm_Idmn, stored as "./dataset/glcm/kernel5/tumor/BraTS2021_00290/original_glcm_Idmn.nrrd"
# Computed original_glcm_Idn, stored as "./dataset/glcm/kernel5/tumor/BraTS2021_00290/original_glcm_Idn.nrrd"
# Computed original_glcm_Imc1, stored as "./dataset/glcm/kernel5/tumor/BraTS2021_00290/original_glcm_Imc1.nrrd"
# Computed original_glcm_Imc2, stored as "./dataset/glcm/kernel5/tumor/BraTS2021_00290/original_glcm_Imc2.nrrd"
# Computed original_glcm_InverseVariance, stored as "./dataset/glcm/kernel5/tumor/BraTS2021_00290/original_glcm_InverseVariance.nrrd"
# Computed original_glcm_JointAverage, stored as "./dataset/glcm/kernel5/tumor/BraTS2021_00290/original_glcm_JointAverage.nrrd"
# Computed original_glcm_JointEnergy, stored as "./dataset/glcm/kernel5/tumor/BraTS2021_00290/original_glcm_JointEnergy.nrrd"
# Computed original_glcm_JointEntropy, stored as "./dataset/glcm/kernel5/tumor/BraTS2021_00290/original_glcm_JointEntropy.nrrd"
# Computed original_glcm_MCC, stored as "./dataset/glcm/kernel5/tumor/BraTS2021_00290/original_glcm_MCC.nrrd"
# Computed original_glcm_MaximumProbability, stored as "./dataset/glcm/kernel5/tumor/BraTS2021_00290/original_glcm_MaximumProbability.nrrd"
# Computed original_glcm_SumAverage, stored as "./dataset/glcm/kernel5/tumor/BraTS2021_00290/original_glcm_SumAverage.nrrd"
# Computed original_glcm_SumEntropy, stored as "./dataset/glcm/kernel5/tumor/BraTS2021_00290/original_glcm_SumEntropy.nrrd"
# Computed original_glcm_SumSquares, stored as "./dataset/glcm/kernel5/tumor/BraTS2021_00290/original_glcm_SumSquares.nrrd"
# Starting BraTS2021_00291
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# Computed original_glcm_Autocorrelation, stored as "./dataset/glcm/kernel5/tumor/BraTS2021_00291/original_glcm_Autocorrelation.nrrd"
# Computed original_glcm_ClusterProminence, stored as "./dataset/glcm/kernel5/tumor/BraTS2021_00291/original_glcm_ClusterProminence.nrrd"
# Computed original_glcm_ClusterShade, stored as "./dataset/glcm/kernel5/tumor/BraTS2021_00291/original_glcm_ClusterShade.nrrd"
# Computed original_glcm_ClusterTendency, stored as "./dataset/glcm/kernel5/tumor/BraTS2021_00291/original_glcm_ClusterTendency.nrrd"
# Computed original_glcm_Contrast, stored as "./dataset/glcm/kernel5/tumor/BraTS2021_00291/original_glcm_Contrast.nrrd"
# Computed original_glcm_Correlation, stored as "./dataset/glcm/kernel5/tumor/BraTS2021_00291/original_glcm_Correlation.nrrd"
# Computed original_glcm_DifferenceAverage, stored as "./dataset/glcm/kernel5/tumor/BraTS2021_00291/original_glcm_DifferenceAverage.nrrd"
# Computed original_glcm_DifferenceEntropy, stored as "./dataset/glcm/kernel5/tumor/BraTS2021_00291/original_glcm_DifferenceEntropy.nrrd"
# Computed original_glcm_DifferenceVariance, stored as "./dataset/glcm/kernel5/tumor/BraTS2021_00291/original_glcm_DifferenceVariance.nrrd"
# Computed original_glcm_Id, stored as "./dataset/glcm/kernel5/tumor/BraTS2021_00291/original_glcm_Id.nrrd"
# Computed original_glcm_Idm, stored as "./dataset/glcm/kernel5/tumor/BraTS2021_00291/original_glcm_Idm.nrrd"
# Computed original_glcm_Idmn, stored as "./dataset/glcm/kernel5/tumor/BraTS2021_00291/original_glcm_Idmn.nrrd"
# Computed original_glcm_Idn, stored as "./dataset/glcm/kernel5/tumor/BraTS2021_00291/original_glcm_Idn.nrrd"
# Computed original_glcm_Imc1, stored as "./dataset/glcm/kernel5/tumor/BraTS2021_00291/original_glcm_Imc1.nrrd"
# Computed original_glcm_Imc2, stored as "./dataset/glcm/kernel5/tumor/BraTS2021_00291/original_glcm_Imc2.nrrd"
# Computed original_glcm_InverseVariance, stored as "./dataset/glcm/kernel5/tumor/BraTS2021_00291/original_glcm_InverseVariance.nrrd"
# Computed original_glcm_JointAverage, stored as "./dataset/glcm/kernel5/tumor/BraTS2021_00291/original_glcm_JointAverage.nrrd"
# Computed original_glcm_JointEnergy, stored as "./dataset/glcm/kernel5/tumor/BraTS2021_00291/original_glcm_JointEnergy.nrrd"
# Computed original_glcm_JointEntropy, stored as "./dataset/glcm/kernel5/tumor/BraTS2021_00291/original_glcm_JointEntropy.nrrd"
# Computed original_glcm_MCC, stored as "./dataset/glcm/kernel5/tumor/BraTS2021_00291/original_glcm_MCC.nrrd"
# Computed original_glcm_MaximumProbability, stored as "./dataset/glcm/kernel5/tumor/BraTS2021_00291/original_glcm_MaximumProbability.nrrd"
# Computed original_glcm_SumAverage, stored as "./dataset/glcm/kernel5/tumor/BraTS2021_00291/original_glcm_SumAverage.nrrd"
# Computed original_glcm_SumEntropy, stored as "./dataset/glcm/kernel5/tumor/BraTS2021_00291/original_glcm_SumEntropy.nrrd"
# Computed original_glcm_SumSquares, stored as "./dataset/glcm/kernel5/tumor/BraTS2021_00291/original_glcm_SumSquares.nrrd"
# Starting BraTS2021_00292
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# Computed original_glcm_Autocorrelation, stored as "./dataset/glcm/kernel5/tumor/BraTS2021_00292/original_glcm_Autocorrelation.nrrd"
# Computed original_glcm_ClusterProminence, stored as "./dataset/glcm/kernel5/tumor/BraTS2021_00292/original_glcm_ClusterProminence.nrrd"
# Computed original_glcm_ClusterShade, stored as "./dataset/glcm/kernel5/tumor/BraTS2021_00292/original_glcm_ClusterShade.nrrd"
# Computed original_glcm_ClusterTendency, stored as "./dataset/glcm/kernel5/tumor/BraTS2021_00292/original_glcm_ClusterTendency.nrrd"
# Computed original_glcm_Contrast, stored as "./dataset/glcm/kernel5/tumor/BraTS2021_00292/original_glcm_Contrast.nrrd"
# Computed original_glcm_Correlation, stored as "./dataset/glcm/kernel5/tumor/BraTS2021_00292/original_glcm_Correlation.nrrd"
# Computed original_glcm_DifferenceAverage, stored as "./dataset/glcm/kernel5/tumor/BraTS2021_00292/original_glcm_DifferenceAverage.nrrd"
# Computed original_glcm_DifferenceEntropy, stored as "./dataset/glcm/kernel5/tumor/BraTS2021_00292/original_glcm_DifferenceEntropy.nrrd"
# Computed original_glcm_DifferenceVariance, stored as "./dataset/glcm/kernel5/tumor/BraTS2021_00292/original_glcm_DifferenceVariance.nrrd"
# Computed original_glcm_Id, stored as "./dataset/glcm/kernel5/tumor/BraTS2021_00292/original_glcm_Id.nrrd"
# Computed original_glcm_Idm, stored as "./dataset/glcm/kernel5/tumor/BraTS2021_00292/original_glcm_Idm.nrrd"
# Computed original_glcm_Idmn, stored as "./dataset/glcm/kernel5/tumor/BraTS2021_00292/original_glcm_Idmn.nrrd"
# Computed original_glcm_Idn, stored as "./dataset/glcm/kernel5/tumor/BraTS2021_00292/original_glcm_Idn.nrrd"
# Computed original_glcm_Imc1, stored as "./dataset/glcm/kernel5/tumor/BraTS2021_00292/original_glcm_Imc1.nrrd"
# Computed original_glcm_Imc2, stored as "./dataset/glcm/kernel5/tumor/BraTS2021_00292/original_glcm_Imc2.nrrd"
# Computed original_glcm_InverseVariance, stored as "./dataset/glcm/kernel5/tumor/BraTS2021_00292/original_glcm_InverseVariance.nrrd"
# Computed original_glcm_JointAverage, stored as "./dataset/glcm/kernel5/tumor/BraTS2021_00292/original_glcm_JointAverage.nrrd"
# Computed original_glcm_JointEnergy, stored as "./dataset/glcm/kernel5/tumor/BraTS2021_00292/original_glcm_JointEnergy.nrrd"
# Computed original_glcm_JointEntropy, stored as "./dataset/glcm/kernel5/tumor/BraTS2021_00292/original_glcm_JointEntropy.nrrd"
# Computed original_glcm_MCC, stored as "./dataset/glcm/kernel5/tumor/BraTS2021_00292/original_glcm_MCC.nrrd"
# Computed original_glcm_MaximumProbability, stored as "./dataset/glcm/kernel5/tumor/BraTS2021_00292/original_glcm_MaximumProbability.nrrd"
# Computed original_glcm_SumAverage, stored as "./dataset/glcm/kernel5/tumor/BraTS2021_00292/original_glcm_SumAverage.nrrd"
# Computed original_glcm_SumEntropy, stored as "./dataset/glcm/kernel5/tumor/BraTS2021_00292/original_glcm_SumEntropy.nrrd"
# Computed original_glcm_SumSquares, stored as "./dataset/glcm/kernel5/tumor/BraTS2021_00292/original_glcm_SumSquares.nrrd"
# Starting BraTS2021_00293
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# Computed original_glcm_Autocorrelation, stored as "./dataset/glcm/kernel5/tumor/BraTS2021_00293/original_glcm_Autocorrelation.nrrd"
# Computed original_glcm_ClusterProminence, stored as "./dataset/glcm/kernel5/tumor/BraTS2021_00293/original_glcm_ClusterProminence.nrrd"
# Computed original_glcm_ClusterShade, stored as "./dataset/glcm/kernel5/tumor/BraTS2021_00293/original_glcm_ClusterShade.nrrd"
# Computed original_glcm_ClusterTendency, stored as "./dataset/glcm/kernel5/tumor/BraTS2021_00293/original_glcm_ClusterTendency.nrrd"
# Computed original_glcm_Contrast, stored as "./dataset/glcm/kernel5/tumor/BraTS2021_00293/original_glcm_Contrast.nrrd"
# Computed original_glcm_Correlation, stored as "./dataset/glcm/kernel5/tumor/BraTS2021_00293/original_glcm_Correlation.nrrd"
# Computed original_glcm_DifferenceAverage, stored as "./dataset/glcm/kernel5/tumor/BraTS2021_00293/original_glcm_DifferenceAverage.nrrd"
# Computed original_glcm_DifferenceEntropy, stored as "./dataset/glcm/kernel5/tumor/BraTS2021_00293/original_glcm_DifferenceEntropy.nrrd"
# Computed original_glcm_DifferenceVariance, stored as "./dataset/glcm/kernel5/tumor/BraTS2021_00293/original_glcm_DifferenceVariance.nrrd"
# Computed original_glcm_Id, stored as "./dataset/glcm/kernel5/tumor/BraTS2021_00293/original_glcm_Id.nrrd"
# Computed original_glcm_Idm, stored as "./dataset/glcm/kernel5/tumor/BraTS2021_00293/original_glcm_Idm.nrrd"
# Computed original_glcm_Idmn, stored as "./dataset/glcm/kernel5/tumor/BraTS2021_00293/original_glcm_Idmn.nrrd"
# Computed original_glcm_Idn, stored as "./dataset/glcm/kernel5/tumor/BraTS2021_00293/original_glcm_Idn.nrrd"
# Computed original_glcm_Imc1, stored as "./dataset/glcm/kernel5/tumor/BraTS2021_00293/original_glcm_Imc1.nrrd"
# Computed original_glcm_Imc2, stored as "./dataset/glcm/kernel5/tumor/BraTS2021_00293/original_glcm_Imc2.nrrd"
# Computed original_glcm_InverseVariance, stored as "./dataset/glcm/kernel5/tumor/BraTS2021_00293/original_glcm_InverseVariance.nrrd"
# Computed original_glcm_JointAverage, stored as "./dataset/glcm/kernel5/tumor/BraTS2021_00293/original_glcm_JointAverage.nrrd"
# Computed original_glcm_JointEnergy, stored as "./dataset/glcm/kernel5/tumor/BraTS2021_00293/original_glcm_JointEnergy.nrrd"
# Computed original_glcm_JointEntropy, stored as "./dataset/glcm/kernel5/tumor/BraTS2021_00293/original_glcm_JointEntropy.nrrd"
# Computed original_glcm_MCC, stored as "./dataset/glcm/kernel5/tumor/BraTS2021_00293/original_glcm_MCC.nrrd"
# Computed original_glcm_MaximumProbability, stored as "./dataset/glcm/kernel5/tumor/BraTS2021_00293/original_glcm_MaximumProbability.nrrd"
# Computed original_glcm_SumAverage, stored as "./dataset/glcm/kernel5/tumor/BraTS2021_00293/original_glcm_SumAverage.nrrd"
# Computed original_glcm_SumEntropy, stored as "./dataset/glcm/kernel5/tumor/BraTS2021_00293/original_glcm_SumEntropy.nrrd"
# Computed original_glcm_SumSquares, stored as "./dataset/glcm/kernel5/tumor/BraTS2021_00293/original_glcm_SumSquares.nrrd"
# Starting BraTS2021_00294
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# Computed original_glcm_Autocorrelation, stored as "./dataset/glcm/kernel5/tumor/BraTS2021_00294/original_glcm_Autocorrelation.nrrd"
# Computed original_glcm_ClusterProminence, stored as "./dataset/glcm/kernel5/tumor/BraTS2021_00294/original_glcm_ClusterProminence.nrrd"
# Computed original_glcm_ClusterShade, stored as "./dataset/glcm/kernel5/tumor/BraTS2021_00294/original_glcm_ClusterShade.nrrd"
# Computed original_glcm_ClusterTendency, stored as "./dataset/glcm/kernel5/tumor/BraTS2021_00294/original_glcm_ClusterTendency.nrrd"
# Computed original_glcm_Contrast, stored as "./dataset/glcm/kernel5/tumor/BraTS2021_00294/original_glcm_Contrast.nrrd"
# Computed original_glcm_Correlation, stored as "./dataset/glcm/kernel5/tumor/BraTS2021_00294/original_glcm_Correlation.nrrd"
# Computed original_glcm_DifferenceAverage, stored as "./dataset/glcm/kernel5/tumor/BraTS2021_00294/original_glcm_DifferenceAverage.nrrd"
# Computed original_glcm_DifferenceEntropy, stored as "./dataset/glcm/kernel5/tumor/BraTS2021_00294/original_glcm_DifferenceEntropy.nrrd"
# Computed original_glcm_DifferenceVariance, stored as "./dataset/glcm/kernel5/tumor/BraTS2021_00294/original_glcm_DifferenceVariance.nrrd"
# Computed original_glcm_Id, stored as "./dataset/glcm/kernel5/tumor/BraTS2021_00294/original_glcm_Id.nrrd"
# Computed original_glcm_Idm, stored as "./dataset/glcm/kernel5/tumor/BraTS2021_00294/original_glcm_Idm.nrrd"
# Computed original_glcm_Idmn, stored as "./dataset/glcm/kernel5/tumor/BraTS2021_00294/original_glcm_Idmn.nrrd"
# Computed original_glcm_Idn, stored as "./dataset/glcm/kernel5/tumor/BraTS2021_00294/original_glcm_Idn.nrrd"
# Computed original_glcm_Imc1, stored as "./dataset/glcm/kernel5/tumor/BraTS2021_00294/original_glcm_Imc1.nrrd"
# Computed original_glcm_Imc2, stored as "./dataset/glcm/kernel5/tumor/BraTS2021_00294/original_glcm_Imc2.nrrd"
# Computed original_glcm_InverseVariance, stored as "./dataset/glcm/kernel5/tumor/BraTS2021_00294/original_glcm_InverseVariance.nrrd"
# Computed original_glcm_JointAverage, stored as "./dataset/glcm/kernel5/tumor/BraTS2021_00294/original_glcm_JointAverage.nrrd"
# Computed original_glcm_JointEnergy, stored as "./dataset/glcm/kernel5/tumor/BraTS2021_00294/original_glcm_JointEnergy.nrrd"
# Computed original_glcm_JointEntropy, stored as "./dataset/glcm/kernel5/tumor/BraTS2021_00294/original_glcm_JointEntropy.nrrd"
# Computed original_glcm_MCC, stored as "./dataset/glcm/kernel5/tumor/BraTS2021_00294/original_glcm_MCC.nrrd"
# Computed original_glcm_MaximumProbability, stored as "./dataset/glcm/kernel5/tumor/BraTS2021_00294/original_glcm_MaximumProbability.nrrd"
# Computed original_glcm_SumAverage, stored as "./dataset/glcm/kernel5/tumor/BraTS2021_00294/original_glcm_SumAverage.nrrd"
# Computed original_glcm_SumEntropy, stored as "./dataset/glcm/kernel5/tumor/BraTS2021_00294/original_glcm_SumEntropy.nrrd"
# Computed original_glcm_SumSquares, stored as "./dataset/glcm/kernel5/tumor/BraTS2021_00294/original_glcm_SumSquares.nrrd"
# Starting BraTS2021_00296
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# Computed original_glcm_Autocorrelation, stored as "./dataset/glcm/kernel5/tumor/BraTS2021_00296/original_glcm_Autocorrelation.nrrd"
# Computed original_glcm_ClusterProminence, stored as "./dataset/glcm/kernel5/tumor/BraTS2021_00296/original_glcm_ClusterProminence.nrrd"
# Computed original_glcm_ClusterShade, stored as "./dataset/glcm/kernel5/tumor/BraTS2021_00296/original_glcm_ClusterShade.nrrd"
# Computed original_glcm_ClusterTendency, stored as "./dataset/glcm/kernel5/tumor/BraTS2021_00296/original_glcm_ClusterTendency.nrrd"
# Computed original_glcm_Contrast, stored as "./dataset/glcm/kernel5/tumor/BraTS2021_00296/original_glcm_Contrast.nrrd"
# Computed original_glcm_Correlation, stored as "./dataset/glcm/kernel5/tumor/BraTS2021_00296/original_glcm_Correlation.nrrd"
# Computed original_glcm_DifferenceAverage, stored as "./dataset/glcm/kernel5/tumor/BraTS2021_00296/original_glcm_DifferenceAverage.nrrd"
# Computed original_glcm_DifferenceEntropy, stored as "./dataset/glcm/kernel5/tumor/BraTS2021_00296/original_glcm_DifferenceEntropy.nrrd"
# Computed original_glcm_DifferenceVariance, stored as "./dataset/glcm/kernel5/tumor/BraTS2021_00296/original_glcm_DifferenceVariance.nrrd"
# Computed original_glcm_Id, stored as "./dataset/glcm/kernel5/tumor/BraTS2021_00296/original_glcm_Id.nrrd"
# Computed original_glcm_Idm, stored as "./dataset/glcm/kernel5/tumor/BraTS2021_00296/original_glcm_Idm.nrrd"
# Computed original_glcm_Idmn, stored as "./dataset/glcm/kernel5/tumor/BraTS2021_00296/original_glcm_Idmn.nrrd"
# Computed original_glcm_Idn, stored as "./dataset/glcm/kernel5/tumor/BraTS2021_00296/original_glcm_Idn.nrrd"
# Computed original_glcm_Imc1, stored as "./dataset/glcm/kernel5/tumor/BraTS2021_00296/original_glcm_Imc1.nrrd"
# Computed original_glcm_Imc2, stored as "./dataset/glcm/kernel5/tumor/BraTS2021_00296/original_glcm_Imc2.nrrd"
# Computed original_glcm_InverseVariance, stored as "./dataset/glcm/kernel5/tumor/BraTS2021_00296/original_glcm_InverseVariance.nrrd"
# Computed original_glcm_JointAverage, stored as "./dataset/glcm/kernel5/tumor/BraTS2021_00296/original_glcm_JointAverage.nrrd"
# Computed original_glcm_JointEnergy, stored as "./dataset/glcm/kernel5/tumor/BraTS2021_00296/original_glcm_JointEnergy.nrrd"
# Computed original_glcm_JointEntropy, stored as "./dataset/glcm/kernel5/tumor/BraTS2021_00296/original_glcm_JointEntropy.nrrd"
# Computed original_glcm_MCC, stored as "./dataset/glcm/kernel5/tumor/BraTS2021_00296/original_glcm_MCC.nrrd"
# Computed original_glcm_MaximumProbability, stored as "./dataset/glcm/kernel5/tumor/BraTS2021_00296/original_glcm_MaximumProbability.nrrd"
# Computed original_glcm_SumAverage, stored as "./dataset/glcm/kernel5/tumor/BraTS2021_00296/original_glcm_SumAverage.nrrd"
# Computed original_glcm_SumEntropy, stored as "./dataset/glcm/kernel5/tumor/BraTS2021_00296/original_glcm_SumEntropy.nrrd"
# Computed original_glcm_SumSquares, stored as "./dataset/glcm/kernel5/tumor/BraTS2021_00296/original_glcm_SumSquares.nrrd"
# Starting BraTS2021_00297
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# Computed original_glcm_Autocorrelation, stored as "./dataset/glcm/kernel5/tumor/BraTS2021_00297/original_glcm_Autocorrelation.nrrd"
# Computed original_glcm_ClusterProminence, stored as "./dataset/glcm/kernel5/tumor/BraTS2021_00297/original_glcm_ClusterProminence.nrrd"
# Computed original_glcm_ClusterShade, stored as "./dataset/glcm/kernel5/tumor/BraTS2021_00297/original_glcm_ClusterShade.nrrd"
# Computed original_glcm_ClusterTendency, stored as "./dataset/glcm/kernel5/tumor/BraTS2021_00297/original_glcm_ClusterTendency.nrrd"
# Computed original_glcm_Contrast, stored as "./dataset/glcm/kernel5/tumor/BraTS2021_00297/original_glcm_Contrast.nrrd"
# Computed original_glcm_Correlation, stored as "./dataset/glcm/kernel5/tumor/BraTS2021_00297/original_glcm_Correlation.nrrd"
# Computed original_glcm_DifferenceAverage, stored as "./dataset/glcm/kernel5/tumor/BraTS2021_00297/original_glcm_DifferenceAverage.nrrd"
# Computed original_glcm_DifferenceEntropy, stored as "./dataset/glcm/kernel5/tumor/BraTS2021_00297/original_glcm_DifferenceEntropy.nrrd"
# Computed original_glcm_DifferenceVariance, stored as "./dataset/glcm/kernel5/tumor/BraTS2021_00297/original_glcm_DifferenceVariance.nrrd"
# Computed original_glcm_Id, stored as "./dataset/glcm/kernel5/tumor/BraTS2021_00297/original_glcm_Id.nrrd"
# Computed original_glcm_Idm, stored as "./dataset/glcm/kernel5/tumor/BraTS2021_00297/original_glcm_Idm.nrrd"
# Computed original_glcm_Idmn, stored as "./dataset/glcm/kernel5/tumor/BraTS2021_00297/original_glcm_Idmn.nrrd"
# Computed original_glcm_Idn, stored as "./dataset/glcm/kernel5/tumor/BraTS2021_00297/original_glcm_Idn.nrrd"
# Computed original_glcm_Imc1, stored as "./dataset/glcm/kernel5/tumor/BraTS2021_00297/original_glcm_Imc1.nrrd"
# Computed original_glcm_Imc2, stored as "./dataset/glcm/kernel5/tumor/BraTS2021_00297/original_glcm_Imc2.nrrd"
# Computed original_glcm_InverseVariance, stored as "./dataset/glcm/kernel5/tumor/BraTS2021_00297/original_glcm_InverseVariance.nrrd"
# Computed original_glcm_JointAverage, stored as "./dataset/glcm/kernel5/tumor/BraTS2021_00297/original_glcm_JointAverage.nrrd"
# Computed original_glcm_JointEnergy, stored as "./dataset/glcm/kernel5/tumor/BraTS2021_00297/original_glcm_JointEnergy.nrrd"
# Computed original_glcm_JointEntropy, stored as "./dataset/glcm/kernel5/tumor/BraTS2021_00297/original_glcm_JointEntropy.nrrd"
# Computed original_glcm_MCC, stored as "./dataset/glcm/kernel5/tumor/BraTS2021_00297/original_glcm_MCC.nrrd"
# Computed original_glcm_MaximumProbability, stored as "./dataset/glcm/kernel5/tumor/BraTS2021_00297/original_glcm_MaximumProbability.nrrd"
# Computed original_glcm_SumAverage, stored as "./dataset/glcm/kernel5/tumor/BraTS2021_00297/original_glcm_SumAverage.nrrd"
# Computed original_glcm_SumEntropy, stored as "./dataset/glcm/kernel5/tumor/BraTS2021_00297/original_glcm_SumEntropy.nrrd"
# Computed original_glcm_SumSquares, stored as "./dataset/glcm/kernel5/tumor/BraTS2021_00297/original_glcm_SumSquares.nrrd"
# Starting BraTS2021_00298
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# Computed original_glcm_Autocorrelation, stored as "./dataset/glcm/kernel5/tumor/BraTS2021_00298/original_glcm_Autocorrelation.nrrd"
# Computed original_glcm_ClusterProminence, stored as "./dataset/glcm/kernel5/tumor/BraTS2021_00298/original_glcm_ClusterProminence.nrrd"
# Computed original_glcm_ClusterShade, stored as "./dataset/glcm/kernel5/tumor/BraTS2021_00298/original_glcm_ClusterShade.nrrd"
# Computed original_glcm_ClusterTendency, stored as "./dataset/glcm/kernel5/tumor/BraTS2021_00298/original_glcm_ClusterTendency.nrrd"
# Computed original_glcm_Contrast, stored as "./dataset/glcm/kernel5/tumor/BraTS2021_00298/original_glcm_Contrast.nrrd"
# Computed original_glcm_Correlation, stored as "./dataset/glcm/kernel5/tumor/BraTS2021_00298/original_glcm_Correlation.nrrd"
# Computed original_glcm_DifferenceAverage, stored as "./dataset/glcm/kernel5/tumor/BraTS2021_00298/original_glcm_DifferenceAverage.nrrd"
# Computed original_glcm_DifferenceEntropy, stored as "./dataset/glcm/kernel5/tumor/BraTS2021_00298/original_glcm_DifferenceEntropy.nrrd"
# Computed original_glcm_DifferenceVariance, stored as "./dataset/glcm/kernel5/tumor/BraTS2021_00298/original_glcm_DifferenceVariance.nrrd"
# Computed original_glcm_Id, stored as "./dataset/glcm/kernel5/tumor/BraTS2021_00298/original_glcm_Id.nrrd"
# Computed original_glcm_Idm, stored as "./dataset/glcm/kernel5/tumor/BraTS2021_00298/original_glcm_Idm.nrrd"
# Computed original_glcm_Idmn, stored as "./dataset/glcm/kernel5/tumor/BraTS2021_00298/original_glcm_Idmn.nrrd"
# Computed original_glcm_Idn, stored as "./dataset/glcm/kernel5/tumor/BraTS2021_00298/original_glcm_Idn.nrrd"
# Computed original_glcm_Imc1, stored as "./dataset/glcm/kernel5/tumor/BraTS2021_00298/original_glcm_Imc1.nrrd"
# Computed original_glcm_Imc2, stored as "./dataset/glcm/kernel5/tumor/BraTS2021_00298/original_glcm_Imc2.nrrd"
# Computed original_glcm_InverseVariance, stored as "./dataset/glcm/kernel5/tumor/BraTS2021_00298/original_glcm_InverseVariance.nrrd"
# Computed original_glcm_JointAverage, stored as "./dataset/glcm/kernel5/tumor/BraTS2021_00298/original_glcm_JointAverage.nrrd"
# Computed original_glcm_JointEnergy, stored as "./dataset/glcm/kernel5/tumor/BraTS2021_00298/original_glcm_JointEnergy.nrrd"
# Computed original_glcm_JointEntropy, stored as "./dataset/glcm/kernel5/tumor/BraTS2021_00298/original_glcm_JointEntropy.nrrd"
# Computed original_glcm_MCC, stored as "./dataset/glcm/kernel5/tumor/BraTS2021_00298/original_glcm_MCC.nrrd"
# Computed original_glcm_MaximumProbability, stored as "./dataset/glcm/kernel5/tumor/BraTS2021_00298/original_glcm_MaximumProbability.nrrd"
# Computed original_glcm_SumAverage, stored as "./dataset/glcm/kernel5/tumor/BraTS2021_00298/original_glcm_SumAverage.nrrd"
# Computed original_glcm_SumEntropy, stored as "./dataset/glcm/kernel5/tumor/BraTS2021_00298/original_glcm_SumEntropy.nrrd"
# Computed original_glcm_SumSquares, stored as "./dataset/glcm/kernel5/tumor/BraTS2021_00298/original_glcm_SumSquares.nrrd"
# Starting BraTS2021_00299
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# Computed original_glcm_Autocorrelation, stored as "./dataset/glcm/kernel5/tumor/BraTS2021_00299/original_glcm_Autocorrelation.nrrd"
# Computed original_glcm_ClusterProminence, stored as "./dataset/glcm/kernel5/tumor/BraTS2021_00299/original_glcm_ClusterProminence.nrrd"
# Computed original_glcm_ClusterShade, stored as "./dataset/glcm/kernel5/tumor/BraTS2021_00299/original_glcm_ClusterShade.nrrd"
# Computed original_glcm_ClusterTendency, stored as "./dataset/glcm/kernel5/tumor/BraTS2021_00299/original_glcm_ClusterTendency.nrrd"
# Computed original_glcm_Contrast, stored as "./dataset/glcm/kernel5/tumor/BraTS2021_00299/original_glcm_Contrast.nrrd"
# Computed original_glcm_Correlation, stored as "./dataset/glcm/kernel5/tumor/BraTS2021_00299/original_glcm_Correlation.nrrd"
# Computed original_glcm_DifferenceAverage, stored as "./dataset/glcm/kernel5/tumor/BraTS2021_00299/original_glcm_DifferenceAverage.nrrd"
# Computed original_glcm_DifferenceEntropy, stored as "./dataset/glcm/kernel5/tumor/BraTS2021_00299/original_glcm_DifferenceEntropy.nrrd"
# Computed original_glcm_DifferenceVariance, stored as "./dataset/glcm/kernel5/tumor/BraTS2021_00299/original_glcm_DifferenceVariance.nrrd"
# Computed original_glcm_Id, stored as "./dataset/glcm/kernel5/tumor/BraTS2021_00299/original_glcm_Id.nrrd"
# Computed original_glcm_Idm, stored as "./dataset/glcm/kernel5/tumor/BraTS2021_00299/original_glcm_Idm.nrrd"
# Computed original_glcm_Idmn, stored as "./dataset/glcm/kernel5/tumor/BraTS2021_00299/original_glcm_Idmn.nrrd"
# Computed original_glcm_Idn, stored as "./dataset/glcm/kernel5/tumor/BraTS2021_00299/original_glcm_Idn.nrrd"
# Computed original_glcm_Imc1, stored as "./dataset/glcm/kernel5/tumor/BraTS2021_00299/original_glcm_Imc1.nrrd"
# Computed original_glcm_Imc2, stored as "./dataset/glcm/kernel5/tumor/BraTS2021_00299/original_glcm_Imc2.nrrd"
# Computed original_glcm_InverseVariance, stored as "./dataset/glcm/kernel5/tumor/BraTS2021_00299/original_glcm_InverseVariance.nrrd"
# Computed original_glcm_JointAverage, stored as "./dataset/glcm/kernel5/tumor/BraTS2021_00299/original_glcm_JointAverage.nrrd"
# Computed original_glcm_JointEnergy, stored as "./dataset/glcm/kernel5/tumor/BraTS2021_00299/original_glcm_JointEnergy.nrrd"
# Computed original_glcm_JointEntropy, stored as "./dataset/glcm/kernel5/tumor/BraTS2021_00299/original_glcm_JointEntropy.nrrd"
# Computed original_glcm_MCC, stored as "./dataset/glcm/kernel5/tumor/BraTS2021_00299/original_glcm_MCC.nrrd"
# Computed original_glcm_MaximumProbability, stored as "./dataset/glcm/kernel5/tumor/BraTS2021_00299/original_glcm_MaximumProbability.nrrd"
# Computed original_glcm_SumAverage, stored as "./dataset/glcm/kernel5/tumor/BraTS2021_00299/original_glcm_SumAverage.nrrd"
# Computed original_glcm_SumEntropy, stored as "./dataset/glcm/kernel5/tumor/BraTS2021_00299/original_glcm_SumEntropy.nrrd"
# Computed original_glcm_SumSquares, stored as "./dataset/glcm/kernel5/tumor/BraTS2021_00299/original_glcm_SumSquares.nrrd"
# Starting BraTS2021_00300
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# Computed original_glcm_Autocorrelation, stored as "./dataset/glcm/kernel5/tumor/BraTS2021_00300/original_glcm_Autocorrelation.nrrd"
# Computed original_glcm_ClusterProminence, stored as "./dataset/glcm/kernel5/tumor/BraTS2021_00300/original_glcm_ClusterProminence.nrrd"
# Computed original_glcm_ClusterShade, stored as "./dataset/glcm/kernel5/tumor/BraTS2021_00300/original_glcm_ClusterShade.nrrd"
# Computed original_glcm_ClusterTendency, stored as "./dataset/glcm/kernel5/tumor/BraTS2021_00300/original_glcm_ClusterTendency.nrrd"
# Computed original_glcm_Contrast, stored as "./dataset/glcm/kernel5/tumor/BraTS2021_00300/original_glcm_Contrast.nrrd"
# Computed original_glcm_Correlation, stored as "./dataset/glcm/kernel5/tumor/BraTS2021_00300/original_glcm_Correlation.nrrd"
# Computed original_glcm_DifferenceAverage, stored as "./dataset/glcm/kernel5/tumor/BraTS2021_00300/original_glcm_DifferenceAverage.nrrd"
# Computed original_glcm_DifferenceEntropy, stored as "./dataset/glcm/kernel5/tumor/BraTS2021_00300/original_glcm_DifferenceEntropy.nrrd"
# Computed original_glcm_DifferenceVariance, stored as "./dataset/glcm/kernel5/tumor/BraTS2021_00300/original_glcm_DifferenceVariance.nrrd"
# Computed original_glcm_Id, stored as "./dataset/glcm/kernel5/tumor/BraTS2021_00300/original_glcm_Id.nrrd"
# Computed original_glcm_Idm, stored as "./dataset/glcm/kernel5/tumor/BraTS2021_00300/original_glcm_Idm.nrrd"
# Computed original_glcm_Idmn, stored as "./dataset/glcm/kernel5/tumor/BraTS2021_00300/original_glcm_Idmn.nrrd"
# Computed original_glcm_Idn, stored as "./dataset/glcm/kernel5/tumor/BraTS2021_00300/original_glcm_Idn.nrrd"
# Computed original_glcm_Imc1, stored as "./dataset/glcm/kernel5/tumor/BraTS2021_00300/original_glcm_Imc1.nrrd"
# Computed original_glcm_Imc2, stored as "./dataset/glcm/kernel5/tumor/BraTS2021_00300/original_glcm_Imc2.nrrd"
# Computed original_glcm_InverseVariance, stored as "./dataset/glcm/kernel5/tumor/BraTS2021_00300/original_glcm_InverseVariance.nrrd"
# Computed original_glcm_JointAverage, stored as "./dataset/glcm/kernel5/tumor/BraTS2021_00300/original_glcm_JointAverage.nrrd"
# Computed original_glcm_JointEnergy, stored as "./dataset/glcm/kernel5/tumor/BraTS2021_00300/original_glcm_JointEnergy.nrrd"
# Computed original_glcm_JointEntropy, stored as "./dataset/glcm/kernel5/tumor/BraTS2021_00300/original_glcm_JointEntropy.nrrd"
# Computed original_glcm_MCC, stored as "./dataset/glcm/kernel5/tumor/BraTS2021_00300/original_glcm_MCC.nrrd"
# Computed original_glcm_MaximumProbability, stored as "./dataset/glcm/kernel5/tumor/BraTS2021_00300/original_glcm_MaximumProbability.nrrd"
# Computed original_glcm_SumAverage, stored as "./dataset/glcm/kernel5/tumor/BraTS2021_00300/original_glcm_SumAverage.nrrd"
# Computed original_glcm_SumEntropy, stored as "./dataset/glcm/kernel5/tumor/BraTS2021_00300/original_glcm_SumEntropy.nrrd"
# Computed original_glcm_SumSquares, stored as "./dataset/glcm/kernel5/tumor/BraTS2021_00300/original_glcm_SumSquares.nrrd"
# Starting BraTS2021_00301
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# Computed original_glcm_Autocorrelation, stored as "./dataset/glcm/kernel5/tumor/BraTS2021_00301/original_glcm_Autocorrelation.nrrd"
# Computed original_glcm_ClusterProminence, stored as "./dataset/glcm/kernel5/tumor/BraTS2021_00301/original_glcm_ClusterProminence.nrrd"
# Computed original_glcm_ClusterShade, stored as "./dataset/glcm/kernel5/tumor/BraTS2021_00301/original_glcm_ClusterShade.nrrd"
# Computed original_glcm_ClusterTendency, stored as "./dataset/glcm/kernel5/tumor/BraTS2021_00301/original_glcm_ClusterTendency.nrrd"
# Computed original_glcm_Contrast, stored as "./dataset/glcm/kernel5/tumor/BraTS2021_00301/original_glcm_Contrast.nrrd"
# Computed original_glcm_Correlation, stored as "./dataset/glcm/kernel5/tumor/BraTS2021_00301/original_glcm_Correlation.nrrd"
# Computed original_glcm_DifferenceAverage, stored as "./dataset/glcm/kernel5/tumor/BraTS2021_00301/original_glcm_DifferenceAverage.nrrd"
# Computed original_glcm_DifferenceEntropy, stored as "./dataset/glcm/kernel5/tumor/BraTS2021_00301/original_glcm_DifferenceEntropy.nrrd"
# Computed original_glcm_DifferenceVariance, stored as "./dataset/glcm/kernel5/tumor/BraTS2021_00301/original_glcm_DifferenceVariance.nrrd"
# Computed original_glcm_Id, stored as "./dataset/glcm/kernel5/tumor/BraTS2021_00301/original_glcm_Id.nrrd"
# Computed original_glcm_Idm, stored as "./dataset/glcm/kernel5/tumor/BraTS2021_00301/original_glcm_Idm.nrrd"
# Computed original_glcm_Idmn, stored as "./dataset/glcm/kernel5/tumor/BraTS2021_00301/original_glcm_Idmn.nrrd"
# Computed original_glcm_Idn, stored as "./dataset/glcm/kernel5/tumor/BraTS2021_00301/original_glcm_Idn.nrrd"
# Computed original_glcm_Imc1, stored as "./dataset/glcm/kernel5/tumor/BraTS2021_00301/original_glcm_Imc1.nrrd"
# Computed original_glcm_Imc2, stored as "./dataset/glcm/kernel5/tumor/BraTS2021_00301/original_glcm_Imc2.nrrd"
# Computed original_glcm_InverseVariance, stored as "./dataset/glcm/kernel5/tumor/BraTS2021_00301/original_glcm_InverseVariance.nrrd"
# Computed original_glcm_JointAverage, stored as "./dataset/glcm/kernel5/tumor/BraTS2021_00301/original_glcm_JointAverage.nrrd"
# Computed original_glcm_JointEnergy, stored as "./dataset/glcm/kernel5/tumor/BraTS2021_00301/original_glcm_JointEnergy.nrrd"
# Computed original_glcm_JointEntropy, stored as "./dataset/glcm/kernel5/tumor/BraTS2021_00301/original_glcm_JointEntropy.nrrd"
# Computed original_glcm_MCC, stored as "./dataset/glcm/kernel5/tumor/BraTS2021_00301/original_glcm_MCC.nrrd"
# Computed original_glcm_MaximumProbability, stored as "./dataset/glcm/kernel5/tumor/BraTS2021_00301/original_glcm_MaximumProbability.nrrd"
# Computed original_glcm_SumAverage, stored as "./dataset/glcm/kernel5/tumor/BraTS2021_00301/original_glcm_SumAverage.nrrd"
# Computed original_glcm_SumEntropy, stored as "./dataset/glcm/kernel5/tumor/BraTS2021_00301/original_glcm_SumEntropy.nrrd"
# Computed original_glcm_SumSquares, stored as "./dataset/glcm/kernel5/tumor/BraTS2021_00301/original_glcm_SumSquares.nrrd"
# Starting BraTS2021_00303
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# Computed original_glcm_Autocorrelation, stored as "./dataset/glcm/kernel5/tumor/BraTS2021_00303/original_glcm_Autocorrelation.nrrd"
# Computed original_glcm_ClusterProminence, stored as "./dataset/glcm/kernel5/tumor/BraTS2021_00303/original_glcm_ClusterProminence.nrrd"
# Computed original_glcm_ClusterShade, stored as "./dataset/glcm/kernel5/tumor/BraTS2021_00303/original_glcm_ClusterShade.nrrd"
# Computed original_glcm_ClusterTendency, stored as "./dataset/glcm/kernel5/tumor/BraTS2021_00303/original_glcm_ClusterTendency.nrrd"
# Computed original_glcm_Contrast, stored as "./dataset/glcm/kernel5/tumor/BraTS2021_00303/original_glcm_Contrast.nrrd"
# Computed original_glcm_Correlation, stored as "./dataset/glcm/kernel5/tumor/BraTS2021_00303/original_glcm_Correlation.nrrd"
# Computed original_glcm_DifferenceAverage, stored as "./dataset/glcm/kernel5/tumor/BraTS2021_00303/original_glcm_DifferenceAverage.nrrd"
# Computed original_glcm_DifferenceEntropy, stored as "./dataset/glcm/kernel5/tumor/BraTS2021_00303/original_glcm_DifferenceEntropy.nrrd"
# Computed original_glcm_DifferenceVariance, stored as "./dataset/glcm/kernel5/tumor/BraTS2021_00303/original_glcm_DifferenceVariance.nrrd"
# Computed original_glcm_Id, stored as "./dataset/glcm/kernel5/tumor/BraTS2021_00303/original_glcm_Id.nrrd"
# Computed original_glcm_Idm, stored as "./dataset/glcm/kernel5/tumor/BraTS2021_00303/original_glcm_Idm.nrrd"
# Computed original_glcm_Idmn, stored as "./dataset/glcm/kernel5/tumor/BraTS2021_00303/original_glcm_Idmn.nrrd"
# Computed original_glcm_Idn, stored as "./dataset/glcm/kernel5/tumor/BraTS2021_00303/original_glcm_Idn.nrrd"
# Computed original_glcm_Imc1, stored as "./dataset/glcm/kernel5/tumor/BraTS2021_00303/original_glcm_Imc1.nrrd"
# Computed original_glcm_Imc2, stored as "./dataset/glcm/kernel5/tumor/BraTS2021_00303/original_glcm_Imc2.nrrd"
# Computed original_glcm_InverseVariance, stored as "./dataset/glcm/kernel5/tumor/BraTS2021_00303/original_glcm_InverseVariance.nrrd"
# Computed original_glcm_JointAverage, stored as "./dataset/glcm/kernel5/tumor/BraTS2021_00303/original_glcm_JointAverage.nrrd"
# Computed original_glcm_JointEnergy, stored as "./dataset/glcm/kernel5/tumor/BraTS2021_00303/original_glcm_JointEnergy.nrrd"
# Computed original_glcm_JointEntropy, stored as "./dataset/glcm/kernel5/tumor/BraTS2021_00303/original_glcm_JointEntropy.nrrd"
# Computed original_glcm_MCC, stored as "./dataset/glcm/kernel5/tumor/BraTS2021_00303/original_glcm_MCC.nrrd"
# Computed original_glcm_MaximumProbability, stored as "./dataset/glcm/kernel5/tumor/BraTS2021_00303/original_glcm_MaximumProbability.nrrd"
# Computed original_glcm_SumAverage, stored as "./dataset/glcm/kernel5/tumor/BraTS2021_00303/original_glcm_SumAverage.nrrd"
# Computed original_glcm_SumEntropy, stored as "./dataset/glcm/kernel5/tumor/BraTS2021_00303/original_glcm_SumEntropy.nrrd"
# Computed original_glcm_SumSquares, stored as "./dataset/glcm/kernel5/tumor/BraTS2021_00303/original_glcm_SumSquares.nrrd"
# Starting BraTS2021_00304
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# Computed original_glcm_Autocorrelation, stored as "./dataset/glcm/kernel5/tumor/BraTS2021_00304/original_glcm_Autocorrelation.nrrd"
# Computed original_glcm_ClusterProminence, stored as "./dataset/glcm/kernel5/tumor/BraTS2021_00304/original_glcm_ClusterProminence.nrrd"
# Computed original_glcm_ClusterShade, stored as "./dataset/glcm/kernel5/tumor/BraTS2021_00304/original_glcm_ClusterShade.nrrd"
# Computed original_glcm_ClusterTendency, stored as "./dataset/glcm/kernel5/tumor/BraTS2021_00304/original_glcm_ClusterTendency.nrrd"
# Computed original_glcm_Contrast, stored as "./dataset/glcm/kernel5/tumor/BraTS2021_00304/original_glcm_Contrast.nrrd"
# Computed original_glcm_Correlation, stored as "./dataset/glcm/kernel5/tumor/BraTS2021_00304/original_glcm_Correlation.nrrd"
# Computed original_glcm_DifferenceAverage, stored as "./dataset/glcm/kernel5/tumor/BraTS2021_00304/original_glcm_DifferenceAverage.nrrd"
# Computed original_glcm_DifferenceEntropy, stored as "./dataset/glcm/kernel5/tumor/BraTS2021_00304/original_glcm_DifferenceEntropy.nrrd"
# Computed original_glcm_DifferenceVariance, stored as "./dataset/glcm/kernel5/tumor/BraTS2021_00304/original_glcm_DifferenceVariance.nrrd"
# Computed original_glcm_Id, stored as "./dataset/glcm/kernel5/tumor/BraTS2021_00304/original_glcm_Id.nrrd"
# Computed original_glcm_Idm, stored as "./dataset/glcm/kernel5/tumor/BraTS2021_00304/original_glcm_Idm.nrrd"
# Computed original_glcm_Idmn, stored as "./dataset/glcm/kernel5/tumor/BraTS2021_00304/original_glcm_Idmn.nrrd"
# Computed original_glcm_Idn, stored as "./dataset/glcm/kernel5/tumor/BraTS2021_00304/original_glcm_Idn.nrrd"
# Computed original_glcm_Imc1, stored as "./dataset/glcm/kernel5/tumor/BraTS2021_00304/original_glcm_Imc1.nrrd"
# Computed original_glcm_Imc2, stored as "./dataset/glcm/kernel5/tumor/BraTS2021_00304/original_glcm_Imc2.nrrd"
# ...
# Computed original_glcm_SumEntropy, stored as "./dataset/glcm/kernel5/tumor/BraTS2021_00574/original_glcm_SumEntropy.nrrd"
# Computed original_glcm_SumSquares, stored as "./dataset/glcm/kernel5/tumor/BraTS2021_00574/original_glcm_SumSquares.nrrd"
# Starting BraTS2021_00575
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# Computed original_glcm_Autocorrelation, stored as "./dataset/glcm/kernel5/tumor/BraTS2021_00575/original_glcm_Autocorrelation.nrrd"
# Computed original_glcm_ClusterProminence, stored as "./dataset/glcm/kernel5/tumor/BraTS2021_00575/original_glcm_ClusterProminence.nrrd"
# Computed original_glcm_ClusterShade, stored as "./dataset/glcm/kernel5/tumor/BraTS2021_00575/original_glcm_ClusterShade.nrrd"
# Computed original_glcm_ClusterTendency, stored as "./dataset/glcm/kernel5/tumor/BraTS2021_00575/original_glcm_ClusterTendency.nrrd"
# Computed original_glcm_Contrast, stored as "./dataset/glcm/kernel5/tumor/BraTS2021_00575/original_glcm_Contrast.nrrd"
# Computed original_glcm_Correlation, stored as "./dataset/glcm/kernel5/tumor/BraTS2021_00575/original_glcm_Correlation.nrrd"
# Computed original_glcm_DifferenceAverage, stored as "./dataset/glcm/kernel5/tumor/BraTS2021_00575/original_glcm_DifferenceAverage.nrrd"
# Computed original_glcm_DifferenceEntropy, stored as "./dataset/glcm/kernel5/tumor/BraTS2021_00575/original_glcm_DifferenceEntropy.nrrd"
# Computed original_glcm_DifferenceVariance, stored as "./dataset/glcm/kernel5/tumor/BraTS2021_00575/original_glcm_DifferenceVariance.nrrd"
# Computed original_glcm_Id, stored as "./dataset/glcm/kernel5/tumor/BraTS2021_00575/original_glcm_Id.nrrd"
# Computed original_glcm_Idm, stored as "./dataset/glcm/kernel5/tumor/BraTS2021_00575/original_glcm_Idm.nrrd"
# Computed original_glcm_Idmn, stored as "./dataset/glcm/kernel5/tumor/BraTS2021_00575/original_glcm_Idmn.nrrd"
# Computed original_glcm_Idn, stored as "./dataset/glcm/kernel5/tumor/BraTS2021_00575/original_glcm_Idn.nrrd"
# Computed original_glcm_Imc1, stored as "./dataset/glcm/kernel5/tumor/BraTS2021_00575/original_glcm_Imc1.nrrd"
# Computed original_glcm_Imc2, stored as "./dataset/glcm/kernel5/tumor/BraTS2021_00575/original_glcm_Imc2.nrrd"
# Computed original_glcm_InverseVariance, stored as "./dataset/glcm/kernel5/tumor/BraTS2021_00575/original_glcm_InverseVariance.nrrd"
# Computed original_glcm_JointAverage, stored as "./dataset/glcm/kernel5/tumor/BraTS2021_00575/original_glcm_JointAverage.nrrd"
# Computed original_glcm_JointEnergy, stored as "./dataset/glcm/kernel5/tumor/BraTS2021_00575/original_glcm_JointEnergy.nrrd"
# Computed original_glcm_JointEntropy, stored as "./dataset/glcm/kernel5/tumor/BraTS2021_00575/original_glcm_JointEntropy.nrrd"
# Computed original_glcm_MCC, stored as "./dataset/glcm/kernel5/tumor/BraTS2021_00575/original_glcm_MCC.nrrd"
# Computed original_glcm_MaximumProbability, stored as "./dataset/glcm/kernel5/tumor/BraTS2021_00575/original_glcm_MaximumProbability.nrrd"
# Computed original_glcm_SumAverage, stored as "./dataset/glcm/kernel5/tumor/BraTS2021_00575/original_glcm_SumAverage.nrrd"
# Computed original_glcm_SumEntropy, stored as "./dataset/glcm/kernel5/tumor/BraTS2021_00575/original_glcm_SumEntropy.nrrd"
# Computed original_glcm_SumSquares, stored as "./dataset/glcm/kernel5/tumor/BraTS2021_00575/original_glcm_SumSquares.nrrd"
# Starting BraTS2021_00576
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# Computed original_glcm_Autocorrelation, stored as "./dataset/glcm/kernel5/tumor/BraTS2021_00576/original_glcm_Autocorrelation.nrrd"
# Computed original_glcm_ClusterProminence, stored as "./dataset/glcm/kernel5/tumor/BraTS2021_00576/original_glcm_ClusterProminence.nrrd"
# Computed original_glcm_ClusterShade, stored as "./dataset/glcm/kernel5/tumor/BraTS2021_00576/original_glcm_ClusterShade.nrrd"
# Computed original_glcm_ClusterTendency, stored as "./dataset/glcm/kernel5/tumor/BraTS2021_00576/original_glcm_ClusterTendency.nrrd"
# Computed original_glcm_Contrast, stored as "./dataset/glcm/kernel5/tumor/BraTS2021_00576/original_glcm_Contrast.nrrd"
# Computed original_glcm_Correlation, stored as "./dataset/glcm/kernel5/tumor/BraTS2021_00576/original_glcm_Correlation.nrrd"
# Computed original_glcm_DifferenceAverage, stored as "./dataset/glcm/kernel5/tumor/BraTS2021_00576/original_glcm_DifferenceAverage.nrrd"
# Computed original_glcm_DifferenceEntropy, stored as "./dataset/glcm/kernel5/tumor/BraTS2021_00576/original_glcm_DifferenceEntropy.nrrd"
# Computed original_glcm_DifferenceVariance, stored as "./dataset/glcm/kernel5/tumor/BraTS2021_00576/original_glcm_DifferenceVariance.nrrd"
# Computed original_glcm_Id, stored as "./dataset/glcm/kernel5/tumor/BraTS2021_00576/original_glcm_Id.nrrd"
# Computed original_glcm_Idm, stored as "./dataset/glcm/kernel5/tumor/BraTS2021_00576/original_glcm_Idm.nrrd"
# Computed original_glcm_Idmn, stored as "./dataset/glcm/kernel5/tumor/BraTS2021_00576/original_glcm_Idmn.nrrd"
# Computed original_glcm_Idn, stored as "./dataset/glcm/kernel5/tumor/BraTS2021_00576/original_glcm_Idn.nrrd"
# Computed original_glcm_Imc1, stored as "./dataset/glcm/kernel5/tumor/BraTS2021_00576/original_glcm_Imc1.nrrd"
# Computed original_glcm_Imc2, stored as "./dataset/glcm/kernel5/tumor/BraTS2021_00576/original_glcm_Imc2.nrrd"
# Computed original_glcm_InverseVariance, stored as "./dataset/glcm/kernel5/tumor/BraTS2021_00576/original_glcm_InverseVariance.nrrd"
# Computed original_glcm_JointAverage, stored as "./dataset/glcm/kernel5/tumor/BraTS2021_00576/original_glcm_JointAverage.nrrd"
# Computed original_glcm_JointEnergy, stored as "./dataset/glcm/kernel5/tumor/BraTS2021_00576/original_glcm_JointEnergy.nrrd"
# Computed original_glcm_JointEntropy, stored as "./dataset/glcm/kernel5/tumor/BraTS2021_00576/original_glcm_JointEntropy.nrrd"
# Computed original_glcm_MCC, stored as "./dataset/glcm/kernel5/tumor/BraTS2021_00576/original_glcm_MCC.nrrd"
# Computed original_glcm_MaximumProbability, stored as "./dataset/glcm/kernel5/tumor/BraTS2021_00576/original_glcm_MaximumProbability.nrrd"
# Computed original_glcm_SumAverage, stored as "./dataset/glcm/kernel5/tumor/BraTS2021_00576/original_glcm_SumAverage.nrrd"
# Computed original_glcm_SumEntropy, stored as "./dataset/glcm/kernel5/tumor/BraTS2021_00576/original_glcm_SumEntropy.nrrd"
# Computed original_glcm_SumSquares, stored as "./dataset/glcm/kernel5/tumor/BraTS2021_00576/original_glcm_SumSquares.nrrd"
# Starting BraTS2021_00577
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# Computed original_glcm_Autocorrelation, stored as "./dataset/glcm/kernel5/tumor/BraTS2021_00577/original_glcm_Autocorrelation.nrrd"
# Computed original_glcm_ClusterProminence, stored as "./dataset/glcm/kernel5/tumor/BraTS2021_00577/original_glcm_ClusterProminence.nrrd"
# Computed original_glcm_ClusterShade, stored as "./dataset/glcm/kernel5/tumor/BraTS2021_00577/original_glcm_ClusterShade.nrrd"
# Computed original_glcm_ClusterTendency, stored as "./dataset/glcm/kernel5/tumor/BraTS2021_00577/original_glcm_ClusterTendency.nrrd"
# Computed original_glcm_Contrast, stored as "./dataset/glcm/kernel5/tumor/BraTS2021_00577/original_glcm_Contrast.nrrd"
# Computed original_glcm_Correlation, stored as "./dataset/glcm/kernel5/tumor/BraTS2021_00577/original_glcm_Correlation.nrrd"
# Computed original_glcm_DifferenceAverage, stored as "./dataset/glcm/kernel5/tumor/BraTS2021_00577/original_glcm_DifferenceAverage.nrrd"
# Computed original_glcm_DifferenceEntropy, stored as "./dataset/glcm/kernel5/tumor/BraTS2021_00577/original_glcm_DifferenceEntropy.nrrd"
# Computed original_glcm_DifferenceVariance, stored as "./dataset/glcm/kernel5/tumor/BraTS2021_00577/original_glcm_DifferenceVariance.nrrd"
# Computed original_glcm_Id, stored as "./dataset/glcm/kernel5/tumor/BraTS2021_00577/original_glcm_Id.nrrd"
# Computed original_glcm_Idm, stored as "./dataset/glcm/kernel5/tumor/BraTS2021_00577/original_glcm_Idm.nrrd"
# Computed original_glcm_Idmn, stored as "./dataset/glcm/kernel5/tumor/BraTS2021_00577/original_glcm_Idmn.nrrd"
# Computed original_glcm_Idn, stored as "./dataset/glcm/kernel5/tumor/BraTS2021_00577/original_glcm_Idn.nrrd"
# Computed original_glcm_Imc1, stored as "./dataset/glcm/kernel5/tumor/BraTS2021_00577/original_glcm_Imc1.nrrd"
# Computed original_glcm_Imc2, stored as "./dataset/glcm/kernel5/tumor/BraTS2021_00577/original_glcm_Imc2.nrrd"
# Computed original_glcm_InverseVariance, stored as "./dataset/glcm/kernel5/tumor/BraTS2021_00577/original_glcm_InverseVariance.nrrd"
# Computed original_glcm_JointAverage, stored as "./dataset/glcm/kernel5/tumor/BraTS2021_00577/original_glcm_JointAverage.nrrd"
# Computed original_glcm_JointEnergy, stored as "./dataset/glcm/kernel5/tumor/BraTS2021_00577/original_glcm_JointEnergy.nrrd"
# Computed original_glcm_JointEntropy, stored as "./dataset/glcm/kernel5/tumor/BraTS2021_00577/original_glcm_JointEntropy.nrrd"
# Computed original_glcm_MCC, stored as "./dataset/glcm/kernel5/tumor/BraTS2021_00577/original_glcm_MCC.nrrd"
# Computed original_glcm_MaximumProbability, stored as "./dataset/glcm/kernel5/tumor/BraTS2021_00577/original_glcm_MaximumProbability.nrrd"
# Computed original_glcm_SumAverage, stored as "./dataset/glcm/kernel5/tumor/BraTS2021_00577/original_glcm_SumAverage.nrrd"
# Computed original_glcm_SumEntropy, stored as "./dataset/glcm/kernel5/tumor/BraTS2021_00577/original_glcm_SumEntropy.nrrd"
# Computed original_glcm_SumSquares, stored as "./dataset/glcm/kernel5/tumor/BraTS2021_00577/original_glcm_SumSquares.nrrd"
# Starting BraTS2021_00578
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# Computed original_glcm_Autocorrelation, stored as "./dataset/glcm/kernel5/tumor/BraTS2021_00578/original_glcm_Autocorrelation.nrrd"
# Computed original_glcm_ClusterProminence, stored as "./dataset/glcm/kernel5/tumor/BraTS2021_00578/original_glcm_ClusterProminence.nrrd"
# Computed original_glcm_ClusterShade, stored as "./dataset/glcm/kernel5/tumor/BraTS2021_00578/original_glcm_ClusterShade.nrrd"
# Computed original_glcm_ClusterTendency, stored as "./dataset/glcm/kernel5/tumor/BraTS2021_00578/original_glcm_ClusterTendency.nrrd"
# Computed original_glcm_Contrast, stored as "./dataset/glcm/kernel5/tumor/BraTS2021_00578/original_glcm_Contrast.nrrd"
# Computed original_glcm_Correlation, stored as "./dataset/glcm/kernel5/tumor/BraTS2021_00578/original_glcm_Correlation.nrrd"
# Computed original_glcm_DifferenceAverage, stored as "./dataset/glcm/kernel5/tumor/BraTS2021_00578/original_glcm_DifferenceAverage.nrrd"
# Computed original_glcm_DifferenceEntropy, stored as "./dataset/glcm/kernel5/tumor/BraTS2021_00578/original_glcm_DifferenceEntropy.nrrd"
# Computed original_glcm_DifferenceVariance, stored as "./dataset/glcm/kernel5/tumor/BraTS2021_00578/original_glcm_DifferenceVariance.nrrd"
# Computed original_glcm_Id, stored as "./dataset/glcm/kernel5/tumor/BraTS2021_00578/original_glcm_Id.nrrd"
# Computed original_glcm_Idm, stored as "./dataset/glcm/kernel5/tumor/BraTS2021_00578/original_glcm_Idm.nrrd"
# Computed original_glcm_Idmn, stored as "./dataset/glcm/kernel5/tumor/BraTS2021_00578/original_glcm_Idmn.nrrd"
# Computed original_glcm_Idn, stored as "./dataset/glcm/kernel5/tumor/BraTS2021_00578/original_glcm_Idn.nrrd"
# Computed original_glcm_Imc1, stored as "./dataset/glcm/kernel5/tumor/BraTS2021_00578/original_glcm_Imc1.nrrd"
# Computed original_glcm_Imc2, stored as "./dataset/glcm/kernel5/tumor/BraTS2021_00578/original_glcm_Imc2.nrrd"
# Computed original_glcm_InverseVariance, stored as "./dataset/glcm/kernel5/tumor/BraTS2021_00578/original_glcm_InverseVariance.nrrd"
# Computed original_glcm_JointAverage, stored as "./dataset/glcm/kernel5/tumor/BraTS2021_00578/original_glcm_JointAverage.nrrd"
# Computed original_glcm_JointEnergy, stored as "./dataset/glcm/kernel5/tumor/BraTS2021_00578/original_glcm_JointEnergy.nrrd"
# Computed original_glcm_JointEntropy, stored as "./dataset/glcm/kernel5/tumor/BraTS2021_00578/original_glcm_JointEntropy.nrrd"
# Computed original_glcm_MCC, stored as "./dataset/glcm/kernel5/tumor/BraTS2021_00578/original_glcm_MCC.nrrd"
# Computed original_glcm_MaximumProbability, stored as "./dataset/glcm/kernel5/tumor/BraTS2021_00578/original_glcm_MaximumProbability.nrrd"
# Computed original_glcm_SumAverage, stored as "./dataset/glcm/kernel5/tumor/BraTS2021_00578/original_glcm_SumAverage.nrrd"
# Computed original_glcm_SumEntropy, stored as "./dataset/glcm/kernel5/tumor/BraTS2021_00578/original_glcm_SumEntropy.nrrd"
# Computed original_glcm_SumSquares, stored as "./dataset/glcm/kernel5/tumor/BraTS2021_00578/original_glcm_SumSquares.nrrd"
# Starting BraTS2021_00579
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# Computed original_glcm_Autocorrelation, stored as "./dataset/glcm/kernel5/tumor/BraTS2021_00579/original_glcm_Autocorrelation.nrrd"
# Computed original_glcm_ClusterProminence, stored as "./dataset/glcm/kernel5/tumor/BraTS2021_00579/original_glcm_ClusterProminence.nrrd"
# Computed original_glcm_ClusterShade, stored as "./dataset/glcm/kernel5/tumor/BraTS2021_00579/original_glcm_ClusterShade.nrrd"
# Computed original_glcm_ClusterTendency, stored as "./dataset/glcm/kernel5/tumor/BraTS2021_00579/original_glcm_ClusterTendency.nrrd"
# Computed original_glcm_Contrast, stored as "./dataset/glcm/kernel5/tumor/BraTS2021_00579/original_glcm_Contrast.nrrd"
# Computed original_glcm_Correlation, stored as "./dataset/glcm/kernel5/tumor/BraTS2021_00579/original_glcm_Correlation.nrrd"
# Computed original_glcm_DifferenceAverage, stored as "./dataset/glcm/kernel5/tumor/BraTS2021_00579/original_glcm_DifferenceAverage.nrrd"
# Computed original_glcm_DifferenceEntropy, stored as "./dataset/glcm/kernel5/tumor/BraTS2021_00579/original_glcm_DifferenceEntropy.nrrd"
# Computed original_glcm_DifferenceVariance, stored as "./dataset/glcm/kernel5/tumor/BraTS2021_00579/original_glcm_DifferenceVariance.nrrd"
# Computed original_glcm_Id, stored as "./dataset/glcm/kernel5/tumor/BraTS2021_00579/original_glcm_Id.nrrd"
# Computed original_glcm_Idm, stored as "./dataset/glcm/kernel5/tumor/BraTS2021_00579/original_glcm_Idm.nrrd"
# Computed original_glcm_Idmn, stored as "./dataset/glcm/kernel5/tumor/BraTS2021_00579/original_glcm_Idmn.nrrd"
# Computed original_glcm_Idn, stored as "./dataset/glcm/kernel5/tumor/BraTS2021_00579/original_glcm_Idn.nrrd"
# Computed original_glcm_Imc1, stored as "./dataset/glcm/kernel5/tumor/BraTS2021_00579/original_glcm_Imc1.nrrd"
# Computed original_glcm_Imc2, stored as "./dataset/glcm/kernel5/tumor/BraTS2021_00579/original_glcm_Imc2.nrrd"
# Computed original_glcm_InverseVariance, stored as "./dataset/glcm/kernel5/tumor/BraTS2021_00579/original_glcm_InverseVariance.nrrd"
# Computed original_glcm_JointAverage, stored as "./dataset/glcm/kernel5/tumor/BraTS2021_00579/original_glcm_JointAverage.nrrd"
# Computed original_glcm_JointEnergy, stored as "./dataset/glcm/kernel5/tumor/BraTS2021_00579/original_glcm_JointEnergy.nrrd"
# Computed original_glcm_JointEntropy, stored as "./dataset/glcm/kernel5/tumor/BraTS2021_00579/original_glcm_JointEntropy.nrrd"
# Computed original_glcm_MCC, stored as "./dataset/glcm/kernel5/tumor/BraTS2021_00579/original_glcm_MCC.nrrd"
# Computed original_glcm_MaximumProbability, stored as "./dataset/glcm/kernel5/tumor/BraTS2021_00579/original_glcm_MaximumProbability.nrrd"
# Computed original_glcm_SumAverage, stored as "./dataset/glcm/kernel5/tumor/BraTS2021_00579/original_glcm_SumAverage.nrrd"
# Computed original_glcm_SumEntropy, stored as "./dataset/glcm/kernel5/tumor/BraTS2021_00579/original_glcm_SumEntropy.nrrd"
# Computed original_glcm_SumSquares, stored as "./dataset/glcm/kernel5/tumor/BraTS2021_00579/original_glcm_SumSquares.nrrd"
# Starting BraTS2021_00580
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
