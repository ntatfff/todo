# %% [markdown]
# # Chia Flair theo mask kernel5_non_tumor (bán kính = 5)
# Notebook này sẽ đọc hai file NIfTI:
# - Flair: dataset/BraTS2021_Training_Data/BraTS2021_00002/BraTS2021_00002_flair.nii.gz
# - Mask kernel5_non_tumor: dataset/BraTS2021_Training_Data/BraTS2021_00002/BraTS2021_00002_kernel5_non_tumor.nii.gz
# Với mỗi voxel có giá trị 1 trong mask, sẽ cắt một khối con từ Flair, tâm tại voxel đó và bán kính 5 (kích thước khối 11x11x11), sau đó lưu từng khối dưới dạng .nii.gz.

# %%
# Đọc NIfTI và cắt khối con theo mask
import numpy as np
import nibabel as nib
from pathlib import Path
import time

def split(fileId: str, radius: int = 5) -> None:
  flair_path = Path(f"dataset/BraTS2021_Training_Data/{fileId}/{fileId}_flair.nii.gz")
  mask_path = Path(f"dataset/BraTS2021_Training_Data/{fileId}/{fileId}_kernel5_tumor.nii.gz")
  output_dir = Path(f"dataset/cnn/k5_r5/tumor")
  output_dir.mkdir(parents=True, exist_ok=True)

  # Kiểm tra tồn tại file
  assert flair_path.exists(), f"Không tìm thấy Flair tại: {flair_path}"
  assert mask_path.exists(), f"Không tìm thấy Mask tại: {mask_path}"

  t0 = time.time()
  flair_img = nib.load(str(flair_path))
  mask_img = nib.load(str(mask_path))

  flair = flair_img.get_fdata()
  mask = mask_img.get_fdata()

  # Kiểm tra kích thước
  assert flair.shape[:3] == mask.shape[:3], f"Shape khác nhau: flair={flair.shape}, mask={mask.shape}"
  shape = flair.shape[:3]

  # Lấy các toạ độ có giá trị 1 trong mask (dùng isclose để tránh sai số kiểu float)
  coords = np.argwhere(np.isclose(mask, 1.0))
  print("Số lượng tâm (value=1) trong mask:", coords.shape[0])

  A = flair_img.affine.copy()
  count = 0

  for (i, j, k) in coords:
      # Xác định phạm vi cắt (bao gồm cả biên, clamp trong [0, dim])
      r = radius
      start_i = max(0, int(i - r))
      start_j = max(0, int(j - r))
      start_k = max(0, int(k - r))
      end_i_ex = min(shape[0], int(i + r + 1))  # end exclusive
      end_j_ex = min(shape[1], int(j + r + 1))
      end_k_ex = min(shape[2], int(k + r + 1))

      patch = flair[start_i:end_i_ex, start_j:end_j_ex, start_k:end_k_ex]

      # Tạo affine mới: gốc (0,0,0) của patch ứng với (start_i, start_j, start_k) trong ảnh gốc
      new_affine = A.copy()
      offset_vox = np.array([start_i, start_j, start_k], dtype=float)
      new_affine[:3, 3] = (A[:3, :3] @ offset_vox) + A[:3, 3]

      # Lưu file NIfTI
      base = flair_path.stem  # ví dụ: BraTS2021_00002_flair
      fname = output_dir / f"{base}_chunk_r{r}_i{i}_j{j}_k{k}.nii.gz"
      nib.save(nib.Nifti1Image(patch, new_affine, flair_img.header), str(fname))
      count += 1

  print(f"{fileId} hoàn tất. Tổng số khối đã lưu: {count} - Thời gian: {time.time() - t0:.2f}s")

# %%
import os

datasetDir = os.path.join('./dataset/BraTS2021_Training_Data')

listDir = os.listdir(datasetDir)
listDir.sort()
listDir
# Iterate over files in directory
listDir = os.listdir(datasetDir)
listDir.sort()
for name in listDir:
  if name.startswith('BraTS2021_'):
    split(name, radius=5)
# Out:
# Số lượng tâm (value=1) trong mask: 141
# BraTS2021_00002 hoàn tất. Tổng số khối đã lưu: 141 - Thời gian: 2.07s
# Số lượng tâm (value=1) trong mask: 72
# BraTS2021_00003 hoàn tất. Tổng số khối đã lưu: 72 - Thời gian: 2.87s
# Số lượng tâm (value=1) trong mask: 95
# BraTS2021_00005 hoàn tất. Tổng số khối đã lưu: 95 - Thời gian: 0.75s
# Số lượng tâm (value=1) trong mask: 104
# BraTS2021_00006 hoàn tất. Tổng số khối đã lưu: 104 - Thời gian: 0.86s
# Số lượng tâm (value=1) trong mask: 14
# BraTS2021_00008 hoàn tất. Tổng số khối đã lưu: 14 - Thời gian: 0.32s
# Số lượng tâm (value=1) trong mask: 21
# BraTS2021_00009 hoàn tất. Tổng số khối đã lưu: 21 - Thời gian: 0.33s
# Số lượng tâm (value=1) trong mask: 51
# BraTS2021_00011 hoàn tất. Tổng số khối đã lưu: 51 - Thời gian: 0.60s
# Số lượng tâm (value=1) trong mask: 196
# BraTS2021_00012 hoàn tất. Tổng số khối đã lưu: 196 - Thời gian: 1.25s
# Số lượng tâm (value=1) trong mask: 31
# BraTS2021_00014 hoàn tất. Tổng số khối đã lưu: 31 - Thời gian: 0.37s
# Số lượng tâm (value=1) trong mask: 57
# BraTS2021_00016 hoàn tất. Tổng số khối đã lưu: 57 - Thời gian: 0.48s
# Số lượng tâm (value=1) trong mask: 74
# BraTS2021_00017 hoàn tất. Tổng số khối đã lưu: 74 - Thời gian: 0.59s
# Số lượng tâm (value=1) trong mask: 126
# BraTS2021_00018 hoàn tất. Tổng số khối đã lưu: 126 - Thời gian: 0.84s
# Số lượng tâm (value=1) trong mask: 99
# BraTS2021_00019 hoàn tất. Tổng số khối đã lưu: 99 - Thời gian: 0.69s
# Số lượng tâm (value=1) trong mask: 46
# BraTS2021_00020 hoàn tất. Tổng số khối đã lưu: 46 - Thời gian: 0.53s
# Số lượng tâm (value=1) trong mask: 67
# BraTS2021_00021 hoàn tất. Tổng số khối đã lưu: 67 - Thời gian: 0.52s
# Số lượng tâm (value=1) trong mask: 90
# BraTS2021_00022 hoàn tất. Tổng số khối đã lưu: 90 - Thời gian: 0.76s
# Số lượng tâm (value=1) trong mask: 77
# BraTS2021_00024 hoàn tất. Tổng số khối đã lưu: 77 - Thời gian: 0.64s
# Số lượng tâm (value=1) trong mask: 21
# BraTS2021_00025 hoàn tất. Tổng số khối đã lưu: 21 - Thời gian: 0.43s
# Số lượng tâm (value=1) trong mask: 52
# BraTS2021_00026 hoàn tất. Tổng số khối đã lưu: 52 - Thời gian: 0.49s
# Số lượng tâm (value=1) trong mask: 20
# BraTS2021_00028 hoàn tất. Tổng số khối đã lưu: 20 - Thời gian: 0.34s
# Số lượng tâm (value=1) trong mask: 89
# BraTS2021_00030 hoàn tất. Tổng số khối đã lưu: 89 - Thời gian: 0.70s
# Số lượng tâm (value=1) trong mask: 175
# BraTS2021_00031 hoàn tất. Tổng số khối đã lưu: 175 - Thời gian: 1.07s
# Số lượng tâm (value=1) trong mask: 66
# BraTS2021_00032 hoàn tất. Tổng số khối đã lưu: 66 - Thời gian: 0.52s
# Số lượng tâm (value=1) trong mask: 123
# BraTS2021_00033 hoàn tất. Tổng số khối đã lưu: 123 - Thời gian: 0.88s
# Số lượng tâm (value=1) trong mask: 30
# BraTS2021_00035 hoàn tất. Tổng số khối đã lưu: 30 - Thời gian: 0.35s
# Số lượng tâm (value=1) trong mask: 123
# BraTS2021_00036 hoàn tất. Tổng số khối đã lưu: 123 - Thời gian: 0.85s
# Số lượng tâm (value=1) trong mask: 73
# BraTS2021_00043 hoàn tất. Tổng số khối đã lưu: 73 - Thời gian: 0.57s
# Số lượng tâm (value=1) trong mask: 14
# BraTS2021_00044 hoàn tất. Tổng số khối đã lưu: 14 - Thời gian: 0.30s
# Số lượng tâm (value=1) trong mask: 26
# BraTS2021_00045 hoàn tất. Tổng số khối đã lưu: 26 - Thời gian: 0.36s
# Số lượng tâm (value=1) trong mask: 27
# BraTS2021_00046 hoàn tất. Tổng số khối đã lưu: 27 - Thời gian: 0.36s
# Số lượng tâm (value=1) trong mask: 65
# BraTS2021_00048 hoàn tất. Tổng số khối đã lưu: 65 - Thời gian: 0.61s
# Số lượng tâm (value=1) trong mask: 97
# BraTS2021_00049 hoàn tất. Tổng số khối đã lưu: 97 - Thời gian: 0.68s
# Số lượng tâm (value=1) trong mask: 84
# BraTS2021_00051 hoàn tất. Tổng số khối đã lưu: 84 - Thời gian: 0.75s
# Số lượng tâm (value=1) trong mask: 125
# BraTS2021_00052 hoàn tất. Tổng số khối đã lưu: 125 - Thời gian: 0.77s
# Số lượng tâm (value=1) trong mask: 105
# BraTS2021_00053 hoàn tất. Tổng số khối đã lưu: 105 - Thời gian: 0.73s
# Số lượng tâm (value=1) trong mask: 72
# BraTS2021_00054 hoàn tất. Tổng số khối đã lưu: 72 - Thời gian: 0.59s
# Số lượng tâm (value=1) trong mask: 78
# BraTS2021_00056 hoàn tất. Tổng số khối đã lưu: 78 - Thời gian: 0.62s
# Số lượng tâm (value=1) trong mask: 18
# BraTS2021_00058 hoàn tất. Tổng số khối đã lưu: 18 - Thời gian: 0.35s
# Số lượng tâm (value=1) trong mask: 86
# BraTS2021_00059 hoàn tất. Tổng số khối đã lưu: 86 - Thời gian: 0.66s
# Số lượng tâm (value=1) trong mask: 177
# BraTS2021_00060 hoàn tất. Tổng số khối đã lưu: 177 - Thời gian: 1.08s
# Số lượng tâm (value=1) trong mask: 15
# BraTS2021_00061 hoàn tất. Tổng số khối đã lưu: 15 - Thời gian: 0.37s
# Số lượng tâm (value=1) trong mask: 93
# BraTS2021_00062 hoàn tất. Tổng số khối đã lưu: 93 - Thời gian: 0.75s
# Số lượng tâm (value=1) trong mask: 16
# BraTS2021_00063 hoàn tất. Tổng số khối đã lưu: 16 - Thời gian: 0.35s
# Số lượng tâm (value=1) trong mask: 70
# BraTS2021_00064 hoàn tất. Tổng số khối đã lưu: 70 - Thời gian: 0.60s
# Số lượng tâm (value=1) trong mask: 31
# BraTS2021_00066 hoàn tất. Tổng số khối đã lưu: 31 - Thời gian: 0.39s
# Số lượng tâm (value=1) trong mask: 83
# BraTS2021_00068 hoàn tất. Tổng số khối đã lưu: 83 - Thời gian: 0.62s
# Số lượng tâm (value=1) trong mask: 118
# BraTS2021_00070 hoàn tất. Tổng số khối đã lưu: 118 - Thời gian: 0.75s
# Số lượng tâm (value=1) trong mask: 70
# BraTS2021_00071 hoàn tất. Tổng số khối đã lưu: 70 - Thời gian: 0.53s
# Số lượng tâm (value=1) trong mask: 53
# BraTS2021_00072 hoàn tất. Tổng số khối đã lưu: 53 - Thời gian: 0.55s
# Số lượng tâm (value=1) trong mask: 135
# BraTS2021_00074 hoàn tất. Tổng số khối đã lưu: 135 - Thời gian: 4.28s
# Số lượng tâm (value=1) trong mask: 145
# BraTS2021_00077 hoàn tất. Tổng số khối đã lưu: 145 - Thời gian: 0.88s
# Số lượng tâm (value=1) trong mask: 54
# BraTS2021_00078 hoàn tất. Tổng số khối đã lưu: 54 - Thời gian: 0.48s
# Số lượng tâm (value=1) trong mask: 58
# BraTS2021_00081 hoàn tất. Tổng số khối đã lưu: 58 - Thời gian: 0.49s
# Số lượng tâm (value=1) trong mask: 55
# BraTS2021_00084 hoàn tất. Tổng số khối đã lưu: 55 - Thời gian: 0.51s
# Số lượng tâm (value=1) trong mask: 64
# BraTS2021_00085 hoàn tất. Tổng số khối đã lưu: 64 - Thời gian: 0.53s
# Số lượng tâm (value=1) trong mask: 89
# BraTS2021_00087 hoàn tất. Tổng số khối đã lưu: 89 - Thời gian: 0.66s
# Số lượng tâm (value=1) trong mask: 96
# BraTS2021_00088 hoàn tất. Tổng số khối đã lưu: 96 - Thời gian: 0.65s
# Số lượng tâm (value=1) trong mask: 25
# BraTS2021_00089 hoàn tất. Tổng số khối đã lưu: 25 - Thời gian: 0.31s
# Số lượng tâm (value=1) trong mask: 76
# BraTS2021_00090 hoàn tất. Tổng số khối đã lưu: 76 - Thời gian: 0.64s
# Số lượng tâm (value=1) trong mask: 125
# BraTS2021_00094 hoàn tất. Tổng số khối đã lưu: 125 - Thời gian: 0.87s
# Số lượng tâm (value=1) trong mask: 179
# BraTS2021_00095 hoàn tất. Tổng số khối đã lưu: 179 - Thời gian: 1.02s
# Số lượng tâm (value=1) trong mask: 90
# BraTS2021_00096 hoàn tất. Tổng số khối đã lưu: 90 - Thời gian: 0.82s
# Số lượng tâm (value=1) trong mask: 34
# BraTS2021_00097 hoàn tất. Tổng số khối đã lưu: 34 - Thời gian: 0.50s
# Số lượng tâm (value=1) trong mask: 54
# BraTS2021_00098 hoàn tất. Tổng số khối đã lưu: 54 - Thời gian: 0.48s
# Số lượng tâm (value=1) trong mask: 63
# BraTS2021_00099 hoàn tất. Tổng số khối đã lưu: 63 - Thời gian: 0.51s
# Số lượng tâm (value=1) trong mask: 75
# BraTS2021_00100 hoàn tất. Tổng số khối đã lưu: 75 - Thời gian: 0.57s
# Số lượng tâm (value=1) trong mask: 43
# BraTS2021_00101 hoàn tất. Tổng số khối đã lưu: 43 - Thời gian: 0.43s
# Số lượng tâm (value=1) trong mask: 9
# BraTS2021_00102 hoàn tất. Tổng số khối đã lưu: 9 - Thời gian: 0.39s
# Số lượng tâm (value=1) trong mask: 172
# BraTS2021_00103 hoàn tất. Tổng số khối đã lưu: 172 - Thời gian: 1.20s
# Số lượng tâm (value=1) trong mask: 58
# BraTS2021_00104 hoàn tất. Tổng số khối đã lưu: 58 - Thời gian: 0.97s
# Số lượng tâm (value=1) trong mask: 126
# BraTS2021_00105 hoàn tất. Tổng số khối đã lưu: 126 - Thời gian: 0.86s
# Số lượng tâm (value=1) trong mask: 174
# BraTS2021_00106 hoàn tất. Tổng số khối đã lưu: 174 - Thời gian: 1.28s
# Số lượng tâm (value=1) trong mask: 63
# BraTS2021_00107 hoàn tất. Tổng số khối đã lưu: 63 - Thời gian: 0.65s
# Số lượng tâm (value=1) trong mask: 58
# BraTS2021_00108 hoàn tất. Tổng số khối đã lưu: 58 - Thời gian: 0.67s
# Số lượng tâm (value=1) trong mask: 106
# BraTS2021_00109 hoàn tất. Tổng số khối đã lưu: 106 - Thời gian: 0.85s
# Số lượng tâm (value=1) trong mask: 69
# BraTS2021_00110 hoàn tất. Tổng số khối đã lưu: 69 - Thời gian: 0.64s
# Số lượng tâm (value=1) trong mask: 124
# BraTS2021_00111 hoàn tất. Tổng số khối đã lưu: 124 - Thời gian: 1.05s
# Số lượng tâm (value=1) trong mask: 73
# BraTS2021_00112 hoàn tất. Tổng số khối đã lưu: 73 - Thời gian: 0.69s
# Số lượng tâm (value=1) trong mask: 27
# BraTS2021_00113 hoàn tất. Tổng số khối đã lưu: 27 - Thời gian: 0.46s
# Số lượng tâm (value=1) trong mask: 68
# BraTS2021_00115 hoàn tất. Tổng số khối đã lưu: 68 - Thời gian: 0.78s
# Số lượng tâm (value=1) trong mask: 126
# BraTS2021_00116 hoàn tất. Tổng số khối đã lưu: 126 - Thời gian: 0.84s
# Số lượng tâm (value=1) trong mask: 57
# BraTS2021_00117 hoàn tất. Tổng số khối đã lưu: 57 - Thời gian: 0.65s
# Số lượng tâm (value=1) trong mask: 108
# BraTS2021_00118 hoàn tất. Tổng số khối đã lưu: 108 - Thời gian: 0.98s
# Số lượng tâm (value=1) trong mask: 72
# BraTS2021_00120 hoàn tất. Tổng số khối đã lưu: 72 - Thời gian: 0.63s
# Số lượng tâm (value=1) trong mask: 54
# BraTS2021_00121 hoàn tất. Tổng số khối đã lưu: 54 - Thời gian: 0.56s
# Số lượng tâm (value=1) trong mask: 35
# BraTS2021_00122 hoàn tất. Tổng số khối đã lưu: 35 - Thời gian: 0.49s
# Số lượng tâm (value=1) trong mask: 172
# BraTS2021_00123 hoàn tất. Tổng số khối đã lưu: 172 - Thời gian: 1.18s
# Số lượng tâm (value=1) trong mask: 135
# BraTS2021_00124 hoàn tất. Tổng số khối đã lưu: 135 - Thời gian: 1.01s
# Số lượng tâm (value=1) trong mask: 115
# BraTS2021_00126 hoàn tất. Tổng số khối đã lưu: 115 - Thời gian: 0.95s
# Số lượng tâm (value=1) trong mask: 81
# BraTS2021_00127 hoàn tất. Tổng số khối đã lưu: 81 - Thời gian: 0.74s
# Số lượng tâm (value=1) trong mask: 101
# BraTS2021_00128 hoàn tất. Tổng số khối đã lưu: 101 - Thời gian: 4.08s
# Số lượng tâm (value=1) trong mask: 112
# BraTS2021_00130 hoàn tất. Tổng số khối đã lưu: 112 - Thời gian: 0.92s
# Số lượng tâm (value=1) trong mask: 78
# BraTS2021_00131 hoàn tất. Tổng số khối đã lưu: 78 - Thời gian: 0.69s
# Số lượng tâm (value=1) trong mask: 99
# BraTS2021_00132 hoàn tất. Tổng số khối đã lưu: 99 - Thời gian: 0.78s
# Số lượng tâm (value=1) trong mask: 62
# BraTS2021_00133 hoàn tất. Tổng số khối đã lưu: 62 - Thời gian: 0.65s
# Số lượng tâm (value=1) trong mask: 122
# BraTS2021_00134 hoàn tất. Tổng số khối đã lưu: 122 - Thời gian: 1.04s
# Số lượng tâm (value=1) trong mask: 42
# BraTS2021_00136 hoàn tất. Tổng số khối đã lưu: 42 - Thời gian: 0.52s
# Số lượng tâm (value=1) trong mask: 145
# BraTS2021_00137 hoàn tất. Tổng số khối đã lưu: 145 - Thời gian: 1.10s
# Số lượng tâm (value=1) trong mask: 119
# BraTS2021_00138 hoàn tất. Tổng số khối đã lưu: 119 - Thời gian: 0.87s
# Số lượng tâm (value=1) trong mask: 59
# BraTS2021_00139 hoàn tất. Tổng số khối đã lưu: 59 - Thời gian: 0.60s
