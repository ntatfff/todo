# %%
# %pip install pandas==2.2.3
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd

# %%
df = pd.read_csv("5-tumor-corrcoef.csv", index_col="no")

# %%
target_df = df[abs(df['corrcoef']) < 0.8]

# %%
target_df.to_csv('5.1-filter-lowest-corrcoef.csv')
# Out:
#                                    feature1  \
# no
# 13    original_firstorder_10Percentile.nrrd
# 18    original_firstorder_10Percentile.nrrd
# 19    original_firstorder_10Percentile.nrrd
# 34    original_firstorder_10Percentile.nrrd
# 51    original_firstorder_10Percentile.nrrd
# ...                                     ...
# 4265       original_glszm_ZoneVariance.nrrd
# 4266       original_glszm_ZoneVariance.nrrd
# 4267       original_glszm_ZoneVariance.nrrd
# 4269           original_ngtdm_Busyness.nrrd
# 4272         original_ngtdm_Coarseness.nrrd
#
#                                      feature2  corrcoef
# no
# 13          original_firstorder_Skewness.nrrd -0.256005
# 18       original_glcm_ClusterProminence.nrrd  0.664913
# 19            original_glcm_ClusterShade.nrrd -0.178710
# 34             original_glcm_JointEnergy.nrrd  0.790078
# 51    original_gldm_LowGrayLevelEmphasis.nrrd  0.722400
# ...                                       ...       ...
# ...
