# %%
# %pip install SimpleITK NumPy
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 19.5/19.5 MB 11.5 MB/s eta 0:00:0000:0100:01
# ...
#
# [notice] A new release of pip is available: 23.0.1 -> 26.0.1
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
import SimpleITK as sitk

# %%
maskPath='dataset/BraTS2021_Training_Data/BraTS2021_00580/BraTS2021_00580_kernel5_tumor.nii.gz'
maskName=sitk.ReadImage(maskPath)

# %%
maskData = sitk.GetArrayFromImage(maskName)

# %%
maskData.max()
# Out:
# np.float32(1.0)

# %%
import numpy as np
np.sum((maskData > 0) & (maskData < 1))
# Out:
# np.int64(0)
